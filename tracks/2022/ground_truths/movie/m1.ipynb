# %% [markdown]
# # General instructions
#
# The goal of the project is to materialize a set of **exploratory workloads** over a real-world, large-scale,  open-domain KG: [WikiData](https://www.wikidata.org/wiki/Wikidata:Main_Page)
#
# An exploratory workload  is composed by a set of queries, where each query is related to the information obtained previously.
#
# An exploratory workload starts with a usually vague, open ended question, and does not assume the person issuing the workload has a clear understanding of the data contained in the target database or its structure.
#
# Remeber that:
#
# 1. All the queries must run in the python notebook
# 2. You can use classes and properties only if you find them via a SPARQL query that must be present in the notebook
# 3. You do not delete useless queries. Keep everything that is synthatically valid
#
# ```
# ?p <http://schema.org/name> ?name .
# ```
#
#     is the BGP returning a human-readable name of a property or a class in Wikidata.

# %%
## SETUP used later
import sys
import os
import json
import pandas as pd
sys.path.insert(1, '/locale/data/jupyter/prando/notebook/sparqlthesis/')
import modules.evaluation as evaluation
from SPARQLWrapper import SPARQLWrapper, JSON


prefixString = """
##-movie1-##
PREFIX wd: <http://www.wikidata.org/entity/> 
PREFIX wdt: <http://www.wikidata.org/prop/direct/> 
PREFIX sc: <http://schema.org/>
"""

# select and construct queries
def run_query(queryString,verbose = True):
    to_run = prefixString + "\n" + queryString

    sparql = SPARQLWrapper("http://gracevirtuoso.dei.unipd.it/sparql")
    sparql.setTimeout(300)
    sparql.setReturnFormat(JSON)
    sparql.setQuery(to_run)

    try :
        results = sparql.query()
        json_results = results.convert()
        if len(json_results['results']['bindings'])==0:
            print("Empty")
            return []
        array = []
        for bindings in json_results['results']['bindings']:
            app =  [ (var, value['value'])  for var, value in bindings.items() ] 
            if verbose:
                print( app)
            array.append(app)
        if verbose:
            print(len(array))
        return array

    except Exception as e :
        print("The operation failed", e)
    
# ASk queries
def run_ask_query(queryString):
    to_run = prefixString + "\n" + queryString

    sparql = SPARQLWrapper("http://gracevirtuoso.dei.unipd.it/sparql")
    sparql.setTimeout(300)
    sparql.setReturnFormat(JSON)
    sparql.setQuery(to_run)

    try :
        return sparql.query().convert()

    except Exception as e :
        print("The operation failed", e)

# %% [markdown]
# # Movie Workflow Series ("Film Genre and composer explorative search")
#
# Consider the following exploratory information need:
#
# > investigate the results concerning the different film genre over years and the composers for the cinema.

# %% [markdown]
# ## Useful URIs for the current workflow
# The following are given:
#
# | IRI           | Description   | Role      |
# | -----------   | -----------   |-----------|
# | `wdt:P1647`   | subproperty   | predicate |
# | `wdt:P31`     | instance of   | predicate |
# | `wdt:P106`    | occupation    | predicate |
# | `wdt:P279`    | subclass      | predicate |
# | `wdt:P27`     | nationality   | predicate |
# | `wdt:P3342`     | Significant person       | predicate |
# | `wd:Q5`| Human       | node |
# | `wd:Q25089`| Woody Allen       | node |

# %% [markdown]
# Also consider
#
# ```
# wd:Q25089 ?p ?obj .
# ```
#
# is the BGP to retrieve all **properties of Woody Allen**
#
# Please consider that when you return a resource, you should return the IRI and the label of the resource. In particular, when the task require you to identify a BGP the result set must always be a list of couples IRI - label.
#
# The workload should:
#
#
# 1. Identify the BGP for films
#
# 2. Identify the BGP for composer
#
# 3. Identify the BGP for film genre
#
# 4. Find how many films are been released in the United States of America from 2010-01-01 to 2015-31-12 for each film genre available (the result set must be genre IRI, label and #films).
#
# 5. Consider the timespan from 2001-01-01 to nowadays. Find the number of films released in this timespan divided by film genre and return only those with more than 50 films released every year (the result set must be genre IRI and label).
#
# 6. Consider the composers of Western films and their country of citizenship. Count the number of Western Films on which worked a composer grouped by country of citizenship and return the top-10 (the result set must be country IRI, label and #films)..
#
# 7. Consider the decades from 1961 to 1970, and from 2001 to 2010 and compare the total number of western films released in each one (the result set must be two couples decade and #western films of that decade).
#
# 8. Consider the decades from 1961 to 1970, and from 2001 to 2010 and select only western films. Then, for each decade, compare the average cast members size per film (the result set must be two couples decade and average cast members size of that decade).

# %%
## startup the evaluation
# setup the file and create the empty json
ipname = "m1.ipynb"
pt = os.getcwd()+os.sep+ipname
evaluation.setup(pt)
# Out:
# The index of this workflow is: 2_5

# %% [markdown]
# ## Task 1

# %%
# properties of Woody Allen
queryString = """
SELECT DISTINCT ?p ?name
WHERE { 
    wd:Q25089 ?p ?obj.
    # ?p sc:name ?name.
} 
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P1003'), ('name', 'National Library of Romania ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1005'), ('name', 'Portuguese National Library ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1006'), ('name', 'Nationale Thesaurus voor Auteurs ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1015'), ('name', 'NORAF ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P103'), ('name', 'native language')]
# [('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('p', 'http://www.wikidata.org/prop/direct/P108'), ('name', 'employer')]
# [('p', 'http://www.wikidata.org/prop/direct/P109'), ('name', 'signature')]
# [('p', 'http://www.wikidata.org/prop/direct/P1150'), ('name', 'Regensburg Classification')]
# [('p', 'http://www.wikidata.org/prop/direct/P1207'), ('name', 'NUKAT ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1220'), ('name', 'Internet Broadway Database person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1233'), ('name', 'Internet Speculative Fiction Database author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1263'), ('name', 'NNDB people ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1266'), ('name', 'AlloCiné person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1273'), ('name', 'CANTIC ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1280'), ('name', 'CONOR.SI ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1283'), ('name', 'filmography')]
# [('p', 'http://www.wikidata.org/prop/direct/P1284'), ('name', 'Munzinger person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1296'), ('name', 'Gran Enciclopèdia Catalana ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1303'), ('name', 'instrument')]
# [('p', 'http://www.wikidata.org/prop/direct/P1309'), ('name', 'EGAXA ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1315'), ('name', 'NLA Trove ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1317'), ('name', 'floruit')]
# [('p', 'http://www.wikidata.org/prop/direct/P1343'), ('name', 'described by source')]
# [('p', 'http://www.wikidata.org/prop/direct/P1368'), ('name', 'LNB ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1375'), ('name', 'NSK ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P138'), ('name', 'named after')]
# [('p', 'http://www.wikidata.org/prop/direct/P1411'), ('name', 'nominated for')]
# [('p', 'http://www.wikidata.org/prop/direct/P1412'), ('name', 'languages spoken, written or signed')]
# [('p', 'http://www.wikidata.org/prop/direct/P1417'), ('name', 'Encyclopædia Britannica Online ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1455'), ('name', 'list of works')]
# [('p', 'http://www.wikidata.org/prop/direct/P1477'), ('name', 'birth name')]
# [('p', 'http://www.wikidata.org/prop/direct/P1559'), ('name', 'name in native language')]
# [('p', 'http://www.wikidata.org/prop/direct/P1580'), ('name', 'University of Barcelona authority ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1607'), ('name', 'Dialnet author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P166'), ('name', 'award received')]
# [('p', 'http://www.wikidata.org/prop/direct/P1695'), ('name', 'NLP ID (unique)')]
# [('p', 'http://www.wikidata.org/prop/direct/P172'), ('name', 'ethnic group')]
# [('p', 'http://www.wikidata.org/prop/direct/P1728'), ('name', 'AllMusic artist ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1741'), ('name', 'GTAA ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P18'), ('name', 'image')]
# [('p', 'http://www.wikidata.org/prop/direct/P1816'), ('name', 'National Portrait Gallery (London) person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1819'), ('name', 'genealogics.org person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P19'), ('name', 'place of birth')]
# [('p', 'http://www.wikidata.org/prop/direct/P1953'), ('name', 'Discogs artist ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1969'), ('name', 'MovieMeter director ID (former scheme)')]
# [('p', 'http://www.wikidata.org/prop/direct/P1977'), ('name', 'Les Archives du Spectacle Person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2019'), ('name', 'AllMovie person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2031'), ('name', 'work period (start)')]
# [('p', 'http://www.wikidata.org/prop/direct/P21'), ('name', 'sex or gender')]
# [('p', 'http://www.wikidata.org/prop/direct/P213'), ('name', 'ISNI')]
# [('p', 'http://www.wikidata.org/prop/direct/P214'), ('name', 'VIAF ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2163'), ('name', 'FAST ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2168'), ('name', 'Swedish Film Database person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2174'), ('name', 'Museum of Modern Art artist ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2188'), ('name', 'BiblioNet author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2190'), ('name', 'C-SPAN person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2191'), ('name', 'Vegetti Catalog of Fantastic Literature NILF ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P22'), ('name', 'father')]
# [('p', 'http://www.wikidata.org/prop/direct/P227'), ('name', 'GND ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2387'), ('name', 'Elonet person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2435'), ('name', 'PORT person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P244'), ('name', 'Library of Congress authority ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P245'), ('name', 'Union List of Artist Names ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2469'), ('name', 'Theatricalia person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P25'), ('name', 'mother')]
# [('p', 'http://www.wikidata.org/prop/direct/P2519'), ('name', 'Scope.dk person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P26'), ('name', 'spouse')]
# [('p', 'http://www.wikidata.org/prop/direct/P2600'), ('name', 'Geni.com profile ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2604'), ('name', 'Kinopoisk person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2605'), ('name', 'ČSFD person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2626'), ('name', 'Danish National Filmography person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2638'), ('name', 'TV.com ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P264'), ('name', 'record label')]
# [('p', 'http://www.wikidata.org/prop/direct/P268'), ('name', 'Bibliothèque nationale de France ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2688'), ('name', 'Box Office Mojo person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P269'), ('name', 'IdRef ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P27'), ('name', 'country of citizenship')]
# [('p', 'http://www.wikidata.org/prop/direct/P271'), ('name', 'CiNii author ID (books)')]
# [('p', 'http://www.wikidata.org/prop/direct/P2734'), ('name', 'Unz Review author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2924'), ('name', 'Great Russian Encyclopedia Online ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2963'), ('name', 'Goodreads author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3056'), ('name', 'TCM Movie Database person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3065'), ('name', 'RERO ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('name', 'instance of')]
# [('p', 'http://www.wikidata.org/prop/direct/P3106'), ('name', 'Guardian topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3136'), ('name', 'elCinema person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3142'), ('name', 'EDb person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3219'), ('name', 'Encyclopædia Universalis ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3222'), ('name', 'NE.se ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3280'), ('name', 'BAnQ author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3305'), ('name', 'KINENOTE person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3348'), ('name', 'National Library of Greece ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3373'), ('name', 'sibling')]
# [('p', 'http://www.wikidata.org/prop/direct/P3417'), ('name', 'Quora topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3430'), ('name', 'SNAC ARK ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P345'), ('name', 'IMDb ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3478'), ('name', 'Songkick artist ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3479'), ('name', 'Omni topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P349'), ('name', 'National Diet Library ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3553'), ('name', 'Zhihu topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3569'), ('name', 'Cultureel Woordenboek ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3630'), ('name', 'Babelio author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P373'), ('name', 'Commons category')]
# [('p', 'http://www.wikidata.org/prop/direct/P3762'), ('name', 'openMLOL author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3782'), ('name', 'Artnet artist ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3788'), ('name', 'BNMM authority ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3846'), ('name', 'DBC author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P396'), ('name', 'SBN author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3987'), ('name', 'SHARE Catalogue author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P40'), ('name', 'child')]
# [('p', 'http://www.wikidata.org/prop/direct/P409'), ('name', 'Libraries Australia ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P4104'), ('name', 'Carnegie Hall agent ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P4208'), ('name', 'Billboard artist ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P4293'), ('name', 'PM20 folder ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P434'), ('name', 'MusicBrainz artist ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P4342'), ('name', 'Store norske leksikon ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P4456'), ('name', 'Internet Off-Broadway Database creditable entity ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P451'), ('name', 'unmarried partner')]
# [('p', 'http://www.wikidata.org/prop/direct/P4619'), ('name', 'National Library of Brazil ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P463'), ('name', 'member of')]
# [('p', 'http://www.wikidata.org/prop/direct/P4638'), ('name', 'The Peerage person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P4657'), ('name', 'The Numbers person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P4985'), ('name', 'TMDb person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5019'), ('name', 'Brockhaus Enzyklopädie online ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5033'), ('name', 'Filmweb.pl person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5034'), ('name', 'National Library of Korea ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5063'), ('name', 'Interlingual Index ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5068'), ('name', 'Flanders Arts Institute person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5121'), ('name', 'All About Jazz musician ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5284'), ('name', 'Douban movie celebrity ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5312'), ('name', 'Kino-teatr.ua person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5361'), ('name', 'BNB person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5414'), ('name', 'The Paris Review interviewee ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5419'), ('name', 'NYRB contributor ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5421'), ('name', 'Trading Card Database person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5491'), ('name', "BD Gest' author ID")]
# [('p', 'http://www.wikidata.org/prop/direct/P5534'), ('name', 'Open Media Database person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5587'), ('name', 'Libris-URI')]
# [('p', 'http://www.wikidata.org/prop/direct/P5617'), ('name', 'Evene ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P569'), ('name', 'date of birth')]
# [('p', 'http://www.wikidata.org/prop/direct/P5739'), ('name', 'Pontificia Università della Santa Croce ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5882'), ('name', 'Muziekweb performer ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5905'), ('name', 'Comic Vine ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6058'), ('name', 'Larousse ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6150'), ('name', 'Academy Awards Database nominee ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6181'), ('name', 'Disney A to Z ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6262'), ('name', 'Fandom article ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6379'), ('name', 'has works in the collection')]
# [('p', 'http://www.wikidata.org/prop/direct/P6394'), ('name', 'ELNET ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P646'), ('name', 'Freebase ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P648'), ('name', 'Open Library ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6656'), ('name', 'BHCL ID (former scheme)')]
# [('p', 'http://www.wikidata.org/prop/direct/P6706'), ('name', 'De Agostini ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6844'), ('name', 'abART person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6870'), ('name', 'Latvian National Encyclopedia Online ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P69'), ('name', 'educated at')]
# [('p', 'http://www.wikidata.org/prop/direct/P691'), ('name', 'NKCR AUT ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7029'), ('name', 'National Library of Russia ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7084'), ('name', 'related category')]
# [('p', 'http://www.wikidata.org/prop/direct/P7214'), ('name', 'Allcinema person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7293'), ('name', 'PLWABN ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P734'), ('name', 'family name')]
# [('p', 'http://www.wikidata.org/prop/direct/P735'), ('name', 'given name')]
# [('p', 'http://www.wikidata.org/prop/direct/P7369'), ('name', 'National Library of Chile ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7400'), ('name', 'LibraryThing author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7699'), ('name', 'National Library of Lithuania ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7700'), ('name', 'Slovak National Library ID (VIAF)')]
# [('p', 'http://www.wikidata.org/prop/direct/P7763'), ('name', 'copyright status as a creator')]
# [('p', 'http://www.wikidata.org/prop/direct/P7803'), ('name', 'Decine21 person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7818'), ('name', 'French Vikidia ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7859'), ('name', 'WorldCat Identities ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7865'), ('name', 'CoBiS author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7902'), ('name', 'Deutsche Biographie (GND) ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7929'), ('name', 'Roglo person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P800'), ('name', 'notable work')]
# [('p', 'http://www.wikidata.org/prop/direct/P8094'), ('name', 'GeneaStar person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8179'), ('name', 'Canadiana NCF ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8189'), ('name', 'National Library of Israel J9U ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8349'), ('name', 'Proleksis enciklopedija ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8385'), ('name', 'IDU person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P856'), ('name', 'official website')]
# [('p', 'http://www.wikidata.org/prop/direct/P8625'), ('name', 'bibliography')]
# [('p', 'http://www.wikidata.org/prop/direct/P866'), ('name', 'Perlentaucher ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8796'), ('name', 'FilmPolski press collection ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8814'), ('name', 'WordNet 3.1 Synset ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8971'), ('name', 'Cinémathèque québécoise person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8974'), ('name', 'SAPA ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8980'), ('name', 'KANTO ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P9037'), ('name', 'BHCL UUID')]
# [('p', 'http://www.wikidata.org/prop/direct/P906'), ('name', 'SELIBR ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P910'), ('name', "topic's main category")]
# [('p', 'http://www.wikidata.org/prop/direct/P9141'), ('name', 'Portal da Literatura ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P935'), ('name', 'Commons gallery')]
# [('p', 'http://www.wikidata.org/prop/direct/P949'), ('name', 'National Library of Israel ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P950'), ('name', 'Biblioteca Nacional de España ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P9743'), ('name', 'Podchaser creator ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P9807'), ('name', 'SNK ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P4283'), ('name', 'LUMIERE director ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8929'), ('name', 'religion or world view')]
# [('p', 'http://www.wikidata.org/prop/direct/P3144'), ('name', 'elFilm person ID')]
# 201

# %%
# Allen as object of the triples, properties incoming
queryString = """
SELECT DISTINCT ?p ?name
WHERE { 
    # ?obj ?p wd:Q25089.
    # ?p sc:name ?name.
} 
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P108'), ('name', 'employer')]
# [('p', 'http://www.wikidata.org/prop/direct/P1269'), ('name', 'facet of')]
# [('p', 'http://www.wikidata.org/prop/direct/P1346'), ('name', 'winner')]
# [('p', 'http://www.wikidata.org/prop/direct/P161'), ('name', 'cast member')]
# [('p', 'http://www.wikidata.org/prop/direct/P170'), ('name', 'creator')]
# [('p', 'http://www.wikidata.org/prop/direct/P175'), ('name', 'performer')]
# [('p', 'http://www.wikidata.org/prop/direct/P180'), ('name', 'depicts')]
# [('p', 'http://www.wikidata.org/prop/direct/P22'), ('name', 'father')]
# [('p', 'http://www.wikidata.org/prop/direct/P26'), ('name', 'spouse')]
# [('p', 'http://www.wikidata.org/prop/direct/P2650'), ('name', 'interested in')]
# [('p', 'http://www.wikidata.org/prop/direct/P301'), ('name', "category's main topic")]
# [('p', 'http://www.wikidata.org/prop/direct/P3373'), ('name', 'sibling')]
# [('p', 'http://www.wikidata.org/prop/direct/P40'), ('name', 'child')]
# [('p', 'http://www.wikidata.org/prop/direct/P451'), ('name', 'unmarried partner')]
# [('p', 'http://www.wikidata.org/prop/direct/P50'), ('name', 'author')]
# [('p', 'http://www.wikidata.org/prop/direct/P57'), ('name', 'director')]
# [('p', 'http://www.wikidata.org/prop/direct/P58'), ('name', 'screenwriter')]
# [('p', 'http://www.wikidata.org/prop/direct/P710'), ('name', 'participant')]
# [('p', 'http://www.wikidata.org/prop/direct/P737'), ('name', 'influenced by')]
# [('p', 'http://www.wikidata.org/prop/direct/P825'), ('name', 'dedicated to')]
# [('p', 'http://www.wikidata.org/prop/direct/P86'), ('name', 'composer')]
# [('p', 'http://www.wikidata.org/prop/direct/P921'), ('name', 'main subject')]
# [('p', 'http://www.wikidata.org/prop/direct/P941'), ('name', 'inspired by')]
# [('p', 'http://www.wikidata.org/prop/direct/P971'), ('name', 'category combines topics')]
# [('p', 'http://www.wikidata.org/prop/direct/P725'), ('name', 'voice actor')]
# [('p', 'http://www.wikidata.org/prop/direct/P1855'), ('name', 'Wikidata property example')]
# [('p', 'http://www.wikidata.org/prop/direct/P1877'), ('name', 'after a work by')]
# [('p', 'http://www.wikidata.org/prop/direct/P87'), ('name', 'librettist')]
# 28

# %%
# use director
queryString = """
SELECT DISTINCT ?obj ?name
WHERE { 
    # ?obj wdt:P57 wd:Q25089 .
    # ?obj sc:name ?name.
} 
LIMIT 10
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('obj', 'http://www.wikidata.org/entity/Q206124'), ('name', 'Midnight in Paris')]
# [('obj', 'http://www.wikidata.org/entity/Q682262'), ('name', 'Alice')]
# [('obj', 'http://www.wikidata.org/entity/Q14511869'), ('name', 'Magic in the Moonlight')]
# [('obj', 'http://www.wikidata.org/entity/Q806092'), ('name', 'Bananas')]
# [('obj', 'http://www.wikidata.org/entity/Q1004531'), ('name', 'Bullets Over Broadway')]
# [('obj', 'http://www.wikidata.org/entity/Q1321004'), ('name', 'You Will Meet a Tall Dark Stranger')]
# [('obj', 'http://www.wikidata.org/entity/Q971865'), ('name', "What's Up, Tiger Lily?")]
# [('obj', 'http://www.wikidata.org/entity/Q729026'), ('name', 'Broadway Danny Rose')]
# [('obj', 'http://www.wikidata.org/entity/Q733677'), ('name', 'Match Point')]
# [('obj', 'http://www.wikidata.org/entity/Q740143'), ('name', 'Husbands and Wives')]
# 10

# %%
# instance of films
queryString = """
SELECT DISTINCT ?inst ?name
WHERE { 
    # ?obj wdt:P57 wd:Q25089 ;
        wdt:P31 ?inst.
    # ?inst sc:name ?name.
}
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('inst', 'http://www.wikidata.org/entity/Q11424'), ('name', 'film')]
# [('inst', 'http://www.wikidata.org/entity/Q506240'), ('name', 'television film')]
# [('inst', 'http://www.wikidata.org/entity/Q5398426'), ('name', 'television series')]
# [('inst', 'http://www.wikidata.org/entity/Q24862'), ('name', 'short film')]
# [('inst', 'http://www.wikidata.org/entity/Q47467768'), ('name', 'operatic production')]
# 5

# %%
### insert the result of TASK 1 in the file
og_uri = "http://www.wikidata.org/entity/Q11424"
og_name = "film"
obj = {"uri":og_uri,"name":og_name}
evaluation.add_result(evaluation.get_index_workflow(pt),"1", evaluation.TYPE_SINGLE ,"uri", [obj] ,"all")
# Out:
# The index of this workflow is: 2_5
# The path is /locale/data/jupyter/prando/notebook/2022/results/workflow2_5.json
# JSON object updated

# %% [markdown]
# `wd:Q11424` -> film

# %% [markdown]
# ## Task 2

# %%
# properties of films
queryString = """
SELECT DISTINCT ?prop ?name
WHERE { 
    # ?film wdt:P31 wd:Q11424;
        # ?prop ?obj.
    # ?prop sc:name ?name.
}
ORDER BY ?name
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('prop', 'http://www.wikidata.org/prop/direct/P7003'), ('name', 'ACMI web ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P3593'), ('name', 'AFI Catalog of Feature Films ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P7118'), ('name', 'AMPAS collections film ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P6151'), ('name', 'ANICA ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P9032'), ('name', 'AVN movie ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P7194'), ('name', 'AZLyrics.com artist ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P9283'), ('name', 'AaRC title ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P6145'), ('name', 'Academy Awards Database film ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P6150'), ('name', 'Academy Awards Database nominee ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P7777'), ('name', 'AdoroCinema film ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P5083'), ('name', 'Adult Film Database film ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P9701'), ('name', 'African Film Database ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P4513'), ('name', 'Africultures movie ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P8895'), ('name', 'All the Tropes identifier')]
# [('prop', 'http://www.wikidata.org/prop/direct/P1562'), ('name', 'AllMovie title ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P1729'), ('name', 'AllMusic album ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P2465'), ('name', 'Allcinema film ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P1265'), ('name', 'AlloCiné film ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P1267'), ('name', 'AlloCiné series ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P5749'), ('name', 'Amazon Standard Identification Number')]
# [('prop', 'http://www.wikidata.org/prop/direct/P8055'), ('name', 'Amazon.com Prime Video ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P3502'), ('name', 'Ameblo username')]
# [('prop', 'http://www.wikidata.org/prop/direct/P5646'), ('name', 'AniDB anime ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P8729'), ('name', 'AniList anime ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P1934'), ('name', 'Animator.ru film ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P1985'), ('name', 'Anime News Network anime ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P1984'), ('name', 'Anime News Network manga ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P5845'), ('name', 'AnimeClick anime ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P5860'), ('name', 'AnimeClick drama ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P5849'), ('name', 'AnimeClick manga ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P2281'), ('name', 'Apple Music album ID (U.S. version)')]
# [('prop', 'http://www.wikidata.org/prop/direct/P9586'), ('name', 'Apple TV movie ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P9751'), ('name', 'Apple TV show ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P5218'), ('name', 'Armenian Cinema ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P9629'), ('name', 'Armeniapedia ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P8294'), ('name', 'AusStage work ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P8295'), ('name', 'AustLit ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P3156'), ('name', 'Australian Classification')]
# [('prop', 'http://www.wikidata.org/prop/direct/P8326'), ('name', 'Australian Classification ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P3218'), ('name', 'Auñamendi ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P3293'), ('name', 'BALaT object ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P9086'), ('name', 'BAMID film rating')]
# [('prop', 'http://www.wikidata.org/prop/direct/P3280'), ('name', 'BAnQ author ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P1823'), ('name', 'BAnQ work ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P6200'), ('name', 'BBC News topic ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P1617'), ('name', 'BBC Things ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P827'), ('name', 'BBC programme ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P2629'), ('name', 'BBFC rating')]
# [('prop', 'http://www.wikidata.org/prop/direct/P8794'), ('name', 'BBFC reference')]
# [('prop', 'http://www.wikidata.org/prop/direct/P4438'), ('name', 'BFI Films, TV and people ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P2703'), ('name', 'BFI National Archive work ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P6211'), ('name', 'BIBSYS work ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P508'), ('name', 'BNCF Thesaurus ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P3976'), ('name', 'BVMC work ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P2581'), ('name', 'BabelNet ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P6196'), ('name', 'Badtaste ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P6367'), ('name', "Bahamut Gamer's Community ACG Database ID")]
# [('prop', 'http://www.wikidata.org/prop/direct/P3997'), ('name', 'Bait La Zemer Ha-Ivri artist ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P3821'), ('name', 'Bangla Movie Database ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P7448'), ('name', 'Basis Wien object ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P4632'), ('name', 'Bechdel Test Movie List ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P4965'), ('name', 'Behind The Voice Actors video game ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P5384'), ('name', 'Behind The Voice Actors film ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P5382'), ('name', 'Behind The Voice Actors franchise ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P5387'), ('name', 'Behind The Voice Actors TV show ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P4254'), ('name', 'Bengali Banglapedia ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P950'), ('name', 'Biblioteca Nacional de España ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P4440'), ('name', 'Biblioteca Nacional de México ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P268'), ('name', 'Bibliothèque nationale de France ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P4933'), ('name', 'Big Cartoon Database ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P6456'), ('name', 'Bilibili video ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P6175'), ('name', 'Bitraga work ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P5499'), ('name', 'Boijmans work ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P8674'), ('name', 'Bollywood Hungama movie ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P7923'), ('name', 'Bollywood Hungama person alphabetic ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P1237'), ('name', 'Box Office Mojo film ID (former scheme)')]
# [('prop', 'http://www.wikidata.org/prop/direct/P8856'), ('name', 'British Phonographic Industry ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P4845'), ('name', 'Bulbapedia article')]
# [('prop', 'http://www.wikidata.org/prop/direct/P7685'), ('name', 'CALS Encyclopedia of Arkansas ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P1273'), ('name', 'CANTIC ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P6452'), ('name', 'CBFC rating')]
# [('prop', 'http://www.wikidata.org/prop/direct/P1890'), ('name', 'CCAB ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P6657'), ('name', 'CHVRS Classification')]
# [('prop', 'http://www.wikidata.org/prop/direct/P8908'), ('name', 'CINE21 film ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P9146'), ('name', 'CITWF title ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P3458'), ('name', 'CNC authorization number')]
# [('prop', 'http://www.wikidata.org/prop/direct/P2758'), ('name', 'CNC film rating (France)')]
# [('prop', 'http://www.wikidata.org/prop/direct/P3402'), ('name', 'CNC film rating (Romania)')]
# [('prop', 'http://www.wikidata.org/prop/direct/P7037'), ('name', 'COURAGE ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P5395'), ('name', 'Canadian Encyclopedia article ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P1670'), ('name', 'Canadiana Authorities ID (former scheme)')]
# [('prop', 'http://www.wikidata.org/prop/direct/P8179'), ('name', 'Canadiana NCF ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P4104'), ('name', 'Carnegie Hall agent ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P5229'), ('name', 'Carnegie Hall work ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P3241'), ('name', 'Catholic Encyclopedia ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P9857'), ('name', 'Center for Turkish Cinema Studies film ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P4861'), ('name', 'Charity Navigator ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P5737'), ('name', 'Chinese Moegirlpedia ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P3128'), ('name', 'CiNetMag film ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P1739'), ('name', 'CiNii book ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P9203'), ('name', 'CineFAN.ro title ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P4665'), ('name', 'CineMagia title ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P7593'), ('name', 'CinePT film ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P8296'), ('name', 'Cinema Context ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P5146'), ('name', 'Cinema Project (Israel) ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P3445'), ('name', 'Cinema of Israel ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P3933'), ('name', 'Cinema.de ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P9204'), ('name', 'CinemaRX title ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P9848'), ('name', 'Cinemaitaliano film ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P3851'), ('name', 'Cinenacional.com movie ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P3077'), ('name', 'Cineplex Germany film ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P7177'), ('name', 'Cinestaan film ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P5791'), ('name', 'Cineuropa film ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P3203'), ('name', 'Ciné-Ressources film ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P4276'), ('name', 'Cinémathèque québécoise work identifier')]
# [('prop', 'http://www.wikidata.org/prop/direct/P7679'), ('name', 'Cinépolis KLIC ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P8958'), ('name', 'ClassInd audiovisual work ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P3216'), ('name', 'ClassInd rating')]
# [('prop', 'http://www.wikidata.org/prop/direct/P5905'), ('name', 'Comic Vine ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P7132'), ('name', 'ComingSoon.it film ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P7091'), ('name', 'Common Sense Media ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P1612'), ('name', 'Commons Institution page')]
# [('prop', 'http://www.wikidata.org/prop/direct/P373'), ('name', 'Commons category')]
# [('prop', 'http://www.wikidata.org/prop/direct/P4765'), ('name', 'Commons compatible image available at URL')]
# [('prop', 'http://www.wikidata.org/prop/direct/P935'), ('name', 'Commons gallery')]
# [('prop', 'http://www.wikidata.org/prop/direct/P2011'), ('name', 'Cooper-Hewitt Person ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P6359'), ('name', 'Crew United title ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P2088'), ('name', 'Crunchbase organization ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P4110'), ('name', 'Crunchyroll ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P3569'), ('name', 'Cultureel Woordenboek ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P5318'), ('name', 'César Award film ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P1707'), ('name', 'DAAO ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P5510'), ('name', 'DEFA film database ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P1292'), ('name', 'DNB editions')]
# [('prop', 'http://www.wikidata.org/prop/direct/P1804'), ('name', 'DNF film ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P356'), ('name', 'DOI')]
# [('prop', 'http://www.wikidata.org/prop/direct/P2942'), ('name', 'Dailymotion channel ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P8708'), ('name', 'Danish educational institution number')]
# [('prop', 'http://www.wikidata.org/prop/direct/P4277'), ('name', 'Daum movie ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P6706'), ('name', 'De Agostini ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P7978'), ('name', 'Decine21 film ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P6164'), ('name', 'Depósito Legal ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P4834'), ('name', 'Deutsche Synchronkartei series ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P3844'), ('name', 'Deutsche Synchronkartei film ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P8359'), ('name', 'Dewey Decimal Classification (works and editions)')]
# [('prop', 'http://www.wikidata.org/prop/direct/P1036'), ('name', 'Dewey Decimal Classification')]
# [('prop', 'http://www.wikidata.org/prop/direct/P7872'), ('name', 'Diccionari del cinema a Catalunya ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P9186'), ('name', 'DicoPolHiS ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P3794'), ('name', 'Dictionary of Sydney ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P1953'), ('name', 'Discogs artist ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P1954'), ('name', 'Discogs master ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P2206'), ('name', 'Discogs release ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P6181'), ('name', 'Disney A to Z ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P7595'), ('name', 'Disney+ movie ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P7596'), ('name', 'Disney+ series ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P4529'), ('name', 'Douban film ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P5284'), ('name', 'Douban movie celebrity ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P7236'), ('name', 'Dove.org work ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P7306'), ('name', 'Downdetector ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P9461'), ('name', 'DzygaMDB film ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P3141'), ('name', 'EDb film ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P7892'), ('name', 'EFIS film ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P2704'), ('name', 'EIDR content ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P2756'), ('name', 'EIRIN film rating')]
# [('prop', 'http://www.wikidata.org/prop/direct/P7222'), ('name', 'Eiga.com movie ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P2897'), ('name', 'Eldoblaje Movie ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P4746'), ('name', 'Elhuyar ZTH ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P2346'), ('name', 'Elonet movie ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P2387'), ('name', 'Elonet person ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P6010'), ('name', 'Encyclopedia of Alabama ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P9545'), ('name', 'Encyclopedia of China Online Database ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P9281'), ('name', 'Encyclopedia of Greater Philadelphia ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P4613'), ('name', 'Encyclopedia of Modern Ukraine ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P3338'), ('name', 'Encyclopedia of Surfing ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P7686'), ('name', 'Encyclopedia of the Great Plains ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P1417'), ('name', 'Encyclopædia Britannica Online ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P3219'), ('name', 'Encyclopædia Universalis ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P6679'), ('name', 'Encyklopedia Teatru Polskiego play ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P7829'), ('name', 'English Vikidia ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P3121'), ('name', 'Epguides ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P8800'), ('name', 'European Film Awards ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P7704'), ('name', 'Europeana entity')]
# [('prop', 'http://www.wikidata.org/prop/direct/P2163'), ('name', 'FAST ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P7665'), ('name', 'FMV World ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P4437'), ('name', 'FPB rating')]
# [('prop', 'http://www.wikidata.org/prop/direct/P1981'), ('name', 'FSK film rating')]
# [('prop', 'http://www.wikidata.org/prop/direct/P8680'), ('name', 'FVLB work ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P2013'), ('name', 'Facebook ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P4003'), ('name', 'Facebook page ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P9118'), ('name', 'Family Video Game Database ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P5693'), ('name', 'Fandango film ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P8125'), ('name', 'Fandango person ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P7970'), ('name', 'FandangoNow ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P6262'), ('name', 'Fandom article ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P4073'), ('name', 'Fandom wiki ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P5820'), ('name', 'Film Indonesia ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P480'), ('name', 'FilmAffinity ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P6762'), ('name', 'FilmFreeway ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P8796'), ('name', 'FilmPolski press collection ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P3495'), ('name', 'FilmPolski.pl ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P5255'), ('name', 'FilmTv.it TV series ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P5253'), ('name', 'FilmTv.it movie ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P7975'), ('name', 'Filmfront film ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P2747'), ('name', 'Filmiroda rating')]
# [('prop', 'http://www.wikidata.org/prop/direct/P9367'), ('name', 'Filmitalia film ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P7519'), ('name', 'Filmový přehled film ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P5233'), ('name', 'Filmow ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P2639'), ('name', 'Filmportal ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P8531'), ('name', 'Filmstarts title ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P8928'), ('name', 'Filmstriben film-ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P3995'), ('name', 'Filmweb.pl ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P5032'), ('name', 'Filmweb.pl film ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P9478'), ('name', 'Finna ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P3267'), ('name', 'Flickr user ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P646'), ('name', 'Freebase ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P7818'), ('name', 'French Vikidia ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P3589'), ('name', 'GCD series ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P3367'), ('name', 'GECD film ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P227'), ('name', 'GND ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P2725'), ('name', 'GOG application ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P7175'), ('name', 'Gaana.com album ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P4769'), ('name', 'GameFAQs game ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P6623'), ('name', 'Gamepedia article ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P6218'), ('name', 'Genius song ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P6420'), ('name', 'Georgian National Filmography ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P5986'), ('name', 'Getty Iconography Authority ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P5247'), ('name', 'Giant Bomb ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P4013'), ('name', 'Giphy username')]
# [('prop', 'http://www.wikidata.org/prop/direct/P1842'), ('name', 'Global Anabaptist Mennonite Encyclopedia Online ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P3962'), ('name', 'Global Trade Item Number')]
# [('prop', 'http://www.wikidata.org/prop/direct/P2969'), ('name', 'Goodreads version/edition ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P8383'), ('name', 'Goodreads work ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P4702'), ('name', 'Google Arts & Culture partner ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P4701'), ('name', 'Google Arts & Culture asset ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P4431'), ('name', 'Google Doodle')]
# [('prop', 'http://www.wikidata.org/prop/direct/P2671'), ('name', 'Google Knowledge Graph ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P5337'), ('name', 'Google News topics ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P6562'), ('name', 'Google Play Movies & TV ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P2847'), ('name', 'Google+ ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P1296'), ('name', 'Gran Enciclopèdia Catalana ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P3106'), ('name', 'Guardian topic ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P9863'), ('name', 'Gujarati Vishwakosh entry')]
# [('prop', 'http://www.wikidata.org/prop/direct/P8298'), ('name', 'HBO Max ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P902'), ('name', 'HDS ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P5909'), ('name', 'HKCAN ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P2883'), ('name', 'HKMDB film ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P5091'), ('name', 'HanCinema drama ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P5108'), ('name', 'HanCinema film ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P8874'), ('name', 'Hong Kong film rating')]
# [('prop', 'http://www.wikidata.org/prop/direct/P6868'), ('name', 'Hoopla artist ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P5680'), ('name', 'Hoopla title ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P2816'), ('name', 'HowLongToBeat ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P6466'), ('name', 'Hulu movie ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P6467'), ('name', 'Hulu series ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P9067'), ('name', 'Hungarian Film Archive ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P5098'), ('name', 'IAFD film ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P5128'), ('name', 'ICAA film catalogue ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P3306'), ('name', 'ICAA rating')]
# [('prop', 'http://www.wikidata.org/prop/direct/P7741'), ('name', 'IDFA film ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P7573'), ('name', 'IFCO rating')]
# [('prop', 'http://www.wikidata.org/prop/direct/P5150'), ('name', 'IGAC rating')]
# [('prop', 'http://www.wikidata.org/prop/direct/P5865'), ('name', 'IGN film ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P5201'), ('name', 'IMDA rating')]
# [('prop', 'http://www.wikidata.org/prop/direct/P345'), ('name', 'IMDb ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P6992'), ('name', 'IMFDB ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P3194'), ('name', 'INA video ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P3428'), ('name', 'INCAA film rating')]
# [('prop', 'http://www.wikidata.org/prop/direct/P4483'), ('name', 'INDUCKS story ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P898'), ('name', 'IPA transcription')]
# [('prop', 'http://www.wikidata.org/prop/direct/P1297'), ('name', 'IRS Employer Identification Number')]
# [('prop', 'http://www.wikidata.org/prop/direct/P3212'), ('name', 'ISAN')]
# [('prop', 'http://www.wikidata.org/prop/direct/P957'), ('name', 'ISBN-10')]
# [('prop', 'http://www.wikidata.org/prop/direct/P212'), ('name', 'ISBN-13')]
# [('prop', 'http://www.wikidata.org/prop/direct/P1274'), ('name', 'ISFDB title ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P213'), ('name', 'ISNI')]
# [('prop', 'http://www.wikidata.org/prop/direct/P3110'), ('name', 'ISzDb film ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P1256'), ('name', 'Iconclass notation')]
# [('prop', 'http://www.wikidata.org/prop/direct/P269'), ('name', 'IdRef ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P5099'), ('name', 'Il mondo dei doppiatori ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P5987'), ('name', 'Indiancine.ma film ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P7953'), ('name', 'Indiegogo project ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P2003'), ('name', 'Instagram username')]
# [('prop', 'http://www.wikidata.org/prop/direct/P6748'), ('name', 'Interactive Fiction Database ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P5063'), ('name', 'Interlingual Index ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P724'), ('name', 'Internet Archive ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P1218'), ('name', 'Internet Broadway Database production ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P1219'), ('name', 'Internet Broadway Database show ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P5794'), ('name', 'Internet Game Database game ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P7932'), ('name', 'Irish playography play ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P3906'), ('name', 'Ishim ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P5151'), ('name', 'Israel Film Fund ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P7822'), ('name', 'Italian Vikidia ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P4399'), ('name', 'Itaú Cultural ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P2400'), ('name', 'JMDb film ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P3650'), ('name', 'JMK film rating')]
# [('prop', 'http://www.wikidata.org/prop/direct/P888'), ('name', 'JSTOR article ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P3827'), ('name', 'JSTOR topic ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P5152'), ('name', 'KAVI rating')]
# [('prop', 'http://www.wikidata.org/prop/direct/P8408'), ('name', 'KBpedia ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P2508'), ('name', 'KINENOTE film ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P3750'), ('name', 'KMDb documentary film ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P3704'), ('name', 'KMDb film ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P1649'), ('name', 'KMDb person ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P3818'), ('name', 'KMRB film rating')]
# [('prop', 'http://www.wikidata.org/prop/direct/P8921'), ('name', 'KOBIS ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P7985'), ('name', 'Kanopy ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P8019'), ('name', 'Kickstarter project ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P2684'), ('name', 'Kijkwijzer rating')]
# [('prop', 'http://www.wikidata.org/prop/direct/P7458'), ('name', 'Kinematoscope film ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P5311'), ('name', 'Kino-teatr.ua film ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P2603'), ('name', 'Kinopoisk film ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P2970'), ('name', 'Kinopolis film ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P8847'), ('name', 'Kinorium movie ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P6760'), ('name', 'Know Your Meme ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P3340'), ('name', 'Kvikmyndir film ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P7211'), ('name', 'LINE BLOG user ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P9525'), ('name', 'LMIC musician ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P4282'), ('name', 'LUMIERE film ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P6058'), ('name', 'Larousse ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P3192'), ('name', 'Last.fm ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P3107'), ('name', 'LdiF ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P6127'), ('name', 'Letterboxd film ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P8999'), ('name', 'Lexikon zum Literatur- und Kulturbetrieb im Österreich der Zwischenkriegszeit ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P7107'), ('name', 'LezWatch.TV show ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P409'), ('name', 'Libraries Australia ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P244'), ('name', 'Library of Congress authority ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P8360'), ('name', 'Library of Congress Classification (works and editions)')]
# [('prop', 'http://www.wikidata.org/prop/direct/P4953'), ('name', 'Library of Congress Genre/Form Terms ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P1144'), ('name', 'Library of Congress Control Number (LCCN) (bibliographic)')]
# [('prop', 'http://www.wikidata.org/prop/direct/P2089'), ('name', 'Library of Congress JukeBox ID (former scheme)')]
# [('prop', 'http://www.wikidata.org/prop/direct/P1085'), ('name', 'LibraryThing work ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P6614'), ('name', 'Libreflix ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P3258'), ('name', 'LiveJournal ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P6520'), ('name', 'Lokalhistoriewiki.no ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P7597'), ('name', 'Lutris game ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P7212'), ('name', 'LyricsTranslate ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P1657'), ('name', 'MPAA film rating')]
# [('prop', 'http://www.wikidata.org/prop/direct/P7631'), ('name', 'MPPDA Digital Archive film ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P8889'), ('name', 'MTRCB rating')]
# [('prop', 'http://www.wikidata.org/prop/direct/P7299'), ('name', 'MUBI film ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P4779'), ('name', 'MYmovies actor ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P4780'), ('name', 'MYmovies movie ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P7204'), ('name', 'Mafab.hu film ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P8918'), ('name', 'Max Movie film ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P1942'), ('name', 'McCune-Reischauer romanization')]
# [('prop', 'http://www.wikidata.org/prop/direct/P6368'), ('name', 'Media Arts Database anime ID (former scheme)')]
# [('prop', 'http://www.wikidata.org/prop/direct/P7117'), ('name', 'Media Arts Database console games ID (former scheme)')]
# [('prop', 'http://www.wikidata.org/prop/direct/P7886'), ('name', 'Media Arts Database ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P9022'), ('name', 'Mediafilm ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P5970'), ('name', 'Medierådet rating')]
# [('prop', 'http://www.wikidata.org/prop/direct/P2826'), ('name', 'Megogo ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P1712'), ('name', 'Metacritic ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P6922'), ('name', 'Metro topic ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P2624'), ('name', 'MetroLyrics ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P6366'), ('name', 'Microsoft Academic ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P5885'), ('name', 'Microsoft Store product ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P2636'), ('name', 'Minkultury film ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P7335'), ('name', 'Mixer game ID (former scheme)')]
# [('prop', 'http://www.wikidata.org/prop/direct/P1933'), ('name', 'MobyGames game ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P9365'), ('name', 'Modernist Commons ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P5495'), ('name', 'Mormon Literature and Creative Arts Database Works ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P8033'), ('name', 'Movie Review Query Engine ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P2509'), ('name', 'Movie Walker film ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P1970'), ('name', 'MovieMeter film ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P5786'), ('name', 'Moviepilot.de film ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P5925'), ('name', 'Moviepilot.de series ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P4784'), ('name', 'Movieplayer TV-series ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P4783'), ('name', 'Movieplayer film ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P5990'), ('name', 'Movies Anywhere ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P8920'), ('name', 'Movist film ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P6458'), ('name', 'Mtime movie ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P6464'), ('name', 'Mtime people ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P2014'), ('name', 'Museum of Modern Art work ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P434'), ('name', 'MusicBrainz artist ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P4404'), ('name', 'MusicBrainz recording ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P5813'), ('name', 'MusicBrainz release ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P436'), ('name', 'MusicBrainz release group ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P1407'), ('name', 'MusicBrainz series ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P435'), ('name', 'MusicBrainz work ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P5882'), ('name', 'Muziekweb performer ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P4086'), ('name', 'MyAnimeList anime ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P4087'), ('name', 'MyAnimeList manga ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P3868'), ('name', 'MyDramaList title ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P3265'), ('name', 'Myspace ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P7140'), ('name', 'München Wiki article ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P2475'), ('name', 'NAVA ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P3222'), ('name', 'NE.se ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P691'), ('name', 'NKCR AUT ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P1055'), ('name', 'NLM Unique ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P1695'), ('name', 'NLP ID (unique)')]
# [('prop', 'http://www.wikidata.org/prop/direct/P2363'), ('name', 'NMHH film rating')]
# [('prop', 'http://www.wikidata.org/prop/direct/P3959'), ('name', 'NNL item ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P1015'), ('name', 'NORAF ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P1375'), ('name', 'NSK ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P1207'), ('name', 'NUKAT ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P6549'), ('name', 'NZ On Screen work ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P8885'), ('name', 'Namuwiki ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P349'), ('name', 'National Diet Library ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P4606'), ('name', 'National Film Board of Canada film ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P4683'), ('name', 'National Gallery of Art artwork ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P4619'), ('name', 'National Library of Brazil ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P949'), ('name', 'National Library of Israel ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P8189'), ('name', 'National Library of Israel J9U ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P7369'), ('name', 'National Library of Chile ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P7699'), ('name', 'National Library of Lithuania ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P6152'), ('name', 'National Portrait Gallery (United States) object ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P7506'), ('name', 'Naver Encyclopedia ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P8673'), ('name', 'Naver movie ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P1874'), ('name', 'Netflix ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P8652'), ('name', 'Netflix maturity rating')]
# [('prop', 'http://www.wikidata.org/prop/direct/P4903'), ('name', 'New Georgia Encyclopedia ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P6900'), ('name', 'NicoNicoPedia ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P7749'), ('name', 'Nomenclature for Museum Cataloging')]
# [('prop', 'http://www.wikidata.org/prop/direct/P1439'), ('name', 'Norwegian filmography ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P243'), ('name', 'OCLC control number')]
# [('prop', 'http://www.wikidata.org/prop/direct/P5331'), ('name', 'OCLC work ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P3138'), ('name', 'OFDb film ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P7327'), ('name', 'OFLC classification')]
# [('prop', 'http://www.wikidata.org/prop/direct/P5163'), ('name', 'Odnoklassniki ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P8286'), ('name', 'Olympedia people ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P1245'), ('name', 'OmegaWiki Defined Meaning')]
# [('prop', 'http://www.wikidata.org/prop/direct/P3479'), ('name', 'Omni topic ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P648'), ('name', 'Open Library ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P3302'), ('name', 'Open Media Database film ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P1430'), ('name', 'OpenPlaques subject ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P6337'), ('name', 'PCGamingWiki ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P7293'), ('name', 'PLWABN ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P905'), ('name', 'PORT film ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P1051'), ('name', 'PSH ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P1236'), ('name', 'Parsons code')]
# [('prop', 'http://www.wikidata.org/prop/direct/P4643'), ('name', 'Philadelphia Museum of Art work ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P3836'), ('name', 'Pinterest username')]
# [('prop', 'http://www.wikidata.org/prop/direct/P5833'), ('name', 'Playbill production ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P9743'), ('name', 'Podchaser creator ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P4515'), ('name', 'Prisma ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P8349'), ('name', 'Proleksis enciklopedija ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P3417'), ('name', 'Quora topic ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P2637'), ('name', 'RARS rating')]
# [('prop', 'http://www.wikidata.org/prop/direct/P6658'), ('name', 'RCQ classification')]
# [('prop', 'http://www.wikidata.org/prop/direct/P3065'), ('name', 'RERO ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P6081'), ('name', 'RIA Novosti reference')]
# [('prop', 'http://www.wikidata.org/prop/direct/P3705'), ('name', 'RITVA Program ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P3834'), ('name', 'RTC film rating')]
# [('prop', 'http://www.wikidata.org/prop/direct/P8392'), ('name', 'Rate Your Music release ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P7775'), ('name', 'RationalWiki ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P5290'), ('name', 'Redump.org ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P6228'), ('name', 'RegiowikiAT ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P6554'), ('name', 'Represent Me ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P5875'), ('name', 'ResearchGate publication ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P2001'), ('name', 'Revised Romanization')]
# [('prop', 'http://www.wikidata.org/prop/direct/P6932'), ('name', 'RogerEbert.com film ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P1258'), ('name', 'Rotten Tomatoes ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P2678'), ('name', 'Russiancinema.ru film ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P906'), ('name', 'SELIBR ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P7523'), ('name', 'SK cinema film ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P1025'), ('name', 'SUDOC editions')]
# [('prop', 'http://www.wikidata.org/prop/direct/P9322'), ('name', 'SVKKL authority ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P6817'), ('name', 'SVT Play ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P370'), ('name', 'Sandbox-String')]
# [('prop', 'http://www.wikidata.org/prop/direct/P7839'), ('name', 'Saregama artist ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P2518'), ('name', 'Scope.dk film ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P6584'), ('name', 'Scripts.com script ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P2908'), ('name', 'SecondHandSongs work ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P6133'), ('name', 'Siamzone film ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P5338'), ('name', 'SilentEra.com film ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P3579'), ('name', 'Sina Weibo user ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P6256'), ('name', 'SinemaTürk film ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P9205'), ('name', 'Sinemalar title ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P2984'), ('name', 'Snapchat username')]
# [('prop', 'http://www.wikidata.org/prop/direct/P3478'), ('name', 'Songkick artist ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P3040'), ('name', 'SoundCloud ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P3854'), ('name', 'Soundtrack Collector ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P3139'), ('name', 'SourehCinema film ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P7827'), ('name', 'Spanish Vikidia ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P1447'), ('name', 'Sports-Reference.com Olympic athlete ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P2205'), ('name', 'Spotify album ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P3145'), ('name', 'Sratim ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P1482'), ('name', 'Stack Exchange tag')]
# [('prop', 'http://www.wikidata.org/prop/direct/P1733'), ('name', 'Steam application ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P4342'), ('name', 'Store norske leksikon ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P8256'), ('name', 'Super Mario Wiki ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P2334'), ('name', 'Swedish Film Database film ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P1316'), ('name', 'Swedish Media Database ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P6474'), ('name', 'Swiss Films ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P6219'), ('name', 'TASS reference')]
# [('prop', 'http://www.wikidata.org/prop/direct/P2631'), ('name', 'TCM Movie Database film ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P2613'), ('name', 'TED talk ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P4983'), ('name', 'TMDb TV series ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P4947'), ('name', 'TMDb movie ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P4985'), ('name', 'TMDb person ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P3804'), ('name', 'TV Guide show ID (former scheme)')]
# [('prop', 'http://www.wikidata.org/prop/direct/P8600'), ('name', 'TV Maze series ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P6383'), ('name', 'TV Spielfilm film ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P6643'), ('name', 'TV Spielfilm series ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P6839'), ('name', 'TV Tropes identifier')]
# [('prop', 'http://www.wikidata.org/prop/direct/P2638'), ('name', 'TV.com ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P7611'), ('name', 'Taiwan Cinema film ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P5829'), ('name', 'Television Academy Foundation show ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P8144'), ('name', 'Ternopil Encyclopedia ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P6134'), ('name', 'Thaifilm ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P9584'), ('name', 'The Criterion Collection film ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P5357'), ('name', 'The Encyclopedia of Science Fiction ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P7952'), ('name', 'The First Amendment Encyclopedia ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P7284'), ('name', 'The Independent topic ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P3634'), ('name', 'The Met object ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P5159'), ('name', 'The New Fund for Cinema and Television (Israel) ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P3808'), ('name', 'The Numbers movie ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P7691'), ('name', 'The Oregon Encyclopedia ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P4204'), ('name', 'The Times of India topic ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P7043'), ('name', 'TheTVDB episode ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P4835'), ('name', 'TheTVDB.com series ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P1242'), ('name', 'Theatricalia play ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P7085'), ('name', 'TikTok username')]
# [('prop', 'http://www.wikidata.org/prop/direct/P8013'), ('name', 'Trakt.tv ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P3365'), ('name', 'Treccani ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P9760'), ('name', "Treccani's Enciclopedia del Cinema ID")]
# [('prop', 'http://www.wikidata.org/prop/direct/P3134'), ('name', 'TripAdvisor ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P7760'), ('name', 'Tubi movie ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P3943'), ('name', 'Tumblr username')]
# [('prop', 'http://www.wikidata.org/prop/direct/P6552'), ('name', 'Twitter user numeric ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P2002'), ('name', 'Twitter username')]
# [('prop', 'http://www.wikidata.org/prop/direct/P1225'), ('name', 'U.S. National Archives Identifier')]
# [('prop', 'http://www.wikidata.org/prop/direct/P4527'), ('name', 'UK Parliament thesaurus ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P2699'), ('name', 'URL')]
# [('prop', 'http://www.wikidata.org/prop/direct/P7555'), ('name', 'UVL game ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P9821'), ('name', 'Unconsenting Media ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P3961'), ('name', 'Unifrance film ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P1580'), ('name', 'University of Barcelona authority ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P3929'), ('name', 'V&A item ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P5659'), ('name', 'VGMdb product ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P214'), ('name', 'VIAF ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P3185'), ('name', 'VK ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P2191'), ('name', 'Vegetti Catalog of Fantastic Literature NILF ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P7591'), ('name', 'VideoGameGeek game ID')]
# ...
# [('prop', 'http://www.wikidata.org/prop/direct/P360'), ('name', 'is a list of')]
# [('prop', 'http://www.wikidata.org/prop/direct/P121'), ('name', 'item operated')]
# [('prop', 'http://www.wikidata.org/prop/direct/P407'), ('name', 'language of work or name')]
# [('prop', 'http://www.wikidata.org/prop/direct/P2936'), ('name', 'language used')]
# [('prop', 'http://www.wikidata.org/prop/direct/P1412'), ('name', 'languages spoken, written or signed')]
# [('prop', 'http://www.wikidata.org/prop/direct/P3132'), ('name', 'last line')]
# [('prop', 'http://www.wikidata.org/prop/direct/P2043'), ('name', 'length')]
# [('prop', 'http://www.wikidata.org/prop/direct/P6224'), ('name', 'level of description')]
# [('prop', 'http://www.wikidata.org/prop/direct/P3308'), ('name', 'lib.reviews ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P87'), ('name', 'librettist')]
# [('prop', 'http://www.wikidata.org/prop/direct/P5026'), ('name', 'lighting designer')]
# [('prop', 'http://www.wikidata.org/prop/direct/P1881'), ('name', 'list of characters')]
# [('prop', 'http://www.wikidata.org/prop/direct/P1811'), ('name', 'list of episodes')]
# [('prop', 'http://www.wikidata.org/prop/direct/P131'), ('name', 'located in the administrative territorial entity')]
# [('prop', 'http://www.wikidata.org/prop/direct/P669'), ('name', 'located on street')]
# [('prop', 'http://www.wikidata.org/prop/direct/P276'), ('name', 'location')]
# [('prop', 'http://www.wikidata.org/prop/direct/P1071'), ('name', 'location of creation')]
# [('prop', 'http://www.wikidata.org/prop/direct/P4647'), ('name', 'location of first performance')]
# [('prop', 'http://www.wikidata.org/prop/direct/P740'), ('name', 'location of formation')]
# [('prop', 'http://www.wikidata.org/prop/direct/P154'), ('name', 'logo image')]
# [('prop', 'http://www.wikidata.org/prop/direct/P676'), ('name', 'lyrics by')]
# [('prop', 'http://www.wikidata.org/prop/direct/P8035'), ('name', 'm3db.com film ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P186'), ('name', 'made from material')]
# [('prop', 'http://www.wikidata.org/prop/direct/P921'), ('name', 'main subject')]
# [('prop', 'http://www.wikidata.org/prop/direct/P126'), ('name', 'maintained by')]
# [('prop', 'http://www.wikidata.org/prop/direct/P4805'), ('name', 'make-up artist')]
# [('prop', 'http://www.wikidata.org/prop/direct/P1557'), ('name', 'manifestation of')]
# [('prop', 'http://www.wikidata.org/prop/direct/P176'), ('name', 'manufacturer')]
# [('prop', 'http://www.wikidata.org/prop/direct/P8345'), ('name', 'media franchise')]
# [('prop', 'http://www.wikidata.org/prop/direct/P463'), ('name', 'member of')]
# [('prop', 'http://www.wikidata.org/prop/direct/P54'), ('name', 'member of sports team')]
# [('prop', 'http://www.wikidata.org/prop/direct/P2899'), ('name', 'minimum age')]
# [('prop', 'http://www.wikidata.org/prop/direct/P5059'), ('name', 'modified version of')]
# [('prop', 'http://www.wikidata.org/prop/direct/P1451'), ('name', 'motto text')]
# [('prop', 'http://www.wikidata.org/prop/direct/P135'), ('name', 'movement')]
# [('prop', 'http://www.wikidata.org/prop/direct/P3300'), ('name', 'musical conductor')]
# [('prop', 'http://www.wikidata.org/prop/direct/P2561'), ('name', 'name')]
# [('prop', 'http://www.wikidata.org/prop/direct/P1814'), ('name', 'name in kana')]
# [('prop', 'http://www.wikidata.org/prop/direct/P1559'), ('name', 'name in native language')]
# [('prop', 'http://www.wikidata.org/prop/direct/P138'), ('name', 'named after')]
# [('prop', 'http://www.wikidata.org/prop/direct/P1810'), ('name', 'named as')]
# [('prop', 'http://www.wikidata.org/prop/direct/P840'), ('name', 'narrative location')]
# [('prop', 'http://www.wikidata.org/prop/direct/P6962'), ('name', 'narrative motif')]
# [('prop', 'http://www.wikidata.org/prop/direct/P2438'), ('name', 'narrator')]
# [('prop', 'http://www.wikidata.org/prop/direct/P1705'), ('name', 'native label')]
# [('prop', 'http://www.wikidata.org/prop/direct/P103'), ('name', 'native language')]
# [('prop', 'http://www.wikidata.org/prop/direct/P1449'), ('name', 'nickname')]
# [('prop', 'http://www.wikidata.org/prop/direct/P4353'), ('name', 'nominated by')]
# [('prop', 'http://www.wikidata.org/prop/direct/P1411'), ('name', 'nominated for')]
# [('prop', 'http://www.wikidata.org/prop/direct/P6500'), ('name', 'non-free artwork image URL')]
# [('prop', 'http://www.wikidata.org/prop/direct/P800'), ('name', 'notable work')]
# [('prop', 'http://www.wikidata.org/prop/direct/P1113'), ('name', 'number of episodes')]
# [('prop', 'http://www.wikidata.org/prop/direct/P1350'), ('name', 'number of matches played/races/starts')]
# [('prop', 'http://www.wikidata.org/prop/direct/P1104'), ('name', 'number of pages')]
# [('prop', 'http://www.wikidata.org/prop/direct/P1132'), ('name', 'number of participants')]
# [('prop', 'http://www.wikidata.org/prop/direct/P2635'), ('name', 'number of parts of this work')]
# [('prop', 'http://www.wikidata.org/prop/direct/P2437'), ('name', 'number of seasons')]
# [('prop', 'http://www.wikidata.org/prop/direct/P5436'), ('name', 'number of viewers/listeners')]
# [('prop', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('prop', 'http://www.wikidata.org/prop/direct/P1581'), ('name', 'official blog')]
# [('prop', 'http://www.wikidata.org/prop/direct/P37'), ('name', 'official language')]
# [('prop', 'http://www.wikidata.org/prop/direct/P1448'), ('name', 'official name')]
# [('prop', 'http://www.wikidata.org/prop/direct/P856'), ('name', 'official website')]
# [('prop', 'http://www.wikidata.org/prop/direct/P5008'), ('name', 'on focus list of Wikimedia project')]
# [('prop', 'http://www.wikidata.org/prop/direct/P306'), ('name', 'operating system')]
# [('prop', 'http://www.wikidata.org/prop/direct/P137'), ('name', 'operator')]
# [('prop', 'http://www.wikidata.org/prop/direct/P449'), ('name', 'original broadcaster')]
# [('prop', 'http://www.wikidata.org/prop/direct/P3803'), ('name', 'original film format')]
# [('prop', 'http://www.wikidata.org/prop/direct/P364'), ('name', 'original language of film or TV show')]
# [('prop', 'http://www.wikidata.org/prop/direct/P127'), ('name', 'owned by')]
# [('prop', 'http://www.wikidata.org/prop/direct/P361'), ('name', 'part of')]
# [('prop', 'http://www.wikidata.org/prop/direct/P179'), ('name', 'part of the series')]
# [('prop', 'http://www.wikidata.org/prop/direct/P710'), ('name', 'participant')]
# [('prop', 'http://www.wikidata.org/prop/direct/P1344'), ('name', 'participant in')]
# [('prop', 'http://www.wikidata.org/prop/direct/P1923'), ('name', 'participating team')]
# [('prop', 'http://www.wikidata.org/prop/direct/P1246'), ('name', 'patent number')]
# [('prop', 'http://www.wikidata.org/prop/direct/P175'), ('name', 'performer')]
# [('prop', 'http://www.wikidata.org/prop/direct/P2959'), ('name', 'permanent duplicated item')]
# [('prop', 'http://www.wikidata.org/prop/direct/P1766'), ('name', 'place name sign')]
# [('prop', 'http://www.wikidata.org/prop/direct/P19'), ('name', 'place of birth')]
# [('prop', 'http://www.wikidata.org/prop/direct/P291'), ('name', 'place of publication')]
# [('prop', 'http://www.wikidata.org/prop/direct/P400'), ('name', 'platform')]
# [('prop', 'http://www.wikidata.org/prop/direct/P9177'), ('name', 'playDB play ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P5940'), ('name', 'plot expanded in')]
# [('prop', 'http://www.wikidata.org/prop/direct/P585'), ('name', 'point in time')]
# [('prop', 'http://www.wikidata.org/prop/direct/P1142'), ('name', 'political ideology')]
# [('prop', 'http://www.wikidata.org/prop/direct/P4634'), ('name', 'premiere type')]
# [('prop', 'http://www.wikidata.org/prop/direct/P1441'), ('name', 'present in work')]
# [('prop', 'http://www.wikidata.org/prop/direct/P5072'), ('name', 'presented in')]
# [('prop', 'http://www.wikidata.org/prop/direct/P371'), ('name', 'presenter')]
# [('prop', 'http://www.wikidata.org/prop/direct/P2284'), ('name', 'price')]
# [('prop', 'http://www.wikidata.org/prop/direct/P2849'), ('name', 'produced by')]
# [('prop', 'http://www.wikidata.org/prop/direct/P4733'), ('name', 'produced sound')]
# [('prop', 'http://www.wikidata.org/prop/direct/P162'), ('name', 'producer')]
# [('prop', 'http://www.wikidata.org/prop/direct/P1056'), ('name', 'product or material produced')]
# [('prop', 'http://www.wikidata.org/prop/direct/P2364'), ('name', 'production code')]
# [('prop', 'http://www.wikidata.org/prop/direct/P272'), ('name', 'production company')]
# [('prop', 'http://www.wikidata.org/prop/direct/P2754'), ('name', 'production date')]
# [('prop', 'http://www.wikidata.org/prop/direct/P2554'), ('name', 'production designer')]
# [('prop', 'http://www.wikidata.org/prop/direct/P443'), ('name', 'pronunciation audio')]
# [('prop', 'http://www.wikidata.org/prop/direct/P742'), ('name', 'pseudonym')]
# [('prop', 'http://www.wikidata.org/prop/direct/P3893'), ('name', 'public domain date')]
# [('prop', 'http://www.wikidata.org/prop/direct/P577'), ('name', 'publication date')]
# [('prop', 'http://www.wikidata.org/prop/direct/P1433'), ('name', 'published in')]
# [('prop', 'http://www.wikidata.org/prop/direct/P123'), ('name', 'publisher')]
# [('prop', 'http://www.wikidata.org/prop/direct/P6166'), ('name', 'quotes work')]
# [('prop', 'http://www.wikidata.org/prop/direct/P4271'), ('name', 'rating')]
# [('prop', 'http://www.wikidata.org/prop/direct/P264'), ('name', 'record label')]
# [('prop', 'http://www.wikidata.org/prop/direct/P483'), ('name', 'recorded at studio or venue')]
# [('prop', 'http://www.wikidata.org/prop/direct/P8546'), ('name', 'recording location')]
# [('prop', 'http://www.wikidata.org/prop/direct/P2550'), ('name', 'recording or performance of')]
# [('prop', 'http://www.wikidata.org/prop/direct/P1652'), ('name', 'referee')]
# [('prop', 'http://www.wikidata.org/prop/direct/P854'), ('name', 'reference URL')]
# [('prop', 'http://www.wikidata.org/prop/direct/P8371'), ('name', 'references work, tradition or theory')]
# [('prop', 'http://www.wikidata.org/prop/direct/P6802'), ('name', 'related image')]
# [('prop', 'http://www.wikidata.org/prop/direct/P611'), ('name', 'religious order')]
# [('prop', 'http://www.wikidata.org/prop/direct/P1366'), ('name', 'replaced by')]
# [('prop', 'http://www.wikidata.org/prop/direct/P2675'), ('name', 'reply to')]
# [('prop', 'http://www.wikidata.org/prop/direct/P4646'), ('name', 'representation of')]
# [('prop', 'http://www.wikidata.org/prop/direct/P1875'), ('name', 'represented by')]
# [('prop', 'http://www.wikidata.org/prop/direct/P551'), ('name', 'residence')]
# [('prop', 'http://www.wikidata.org/prop/direct/P444'), ('name', 'review score')]
# [('prop', 'http://www.wikidata.org/prop/direct/P447'), ('name', 'review score by')]
# [('prop', 'http://www.wikidata.org/prop/direct/P460'), ('name', 'said to be the same as')]
# [('prop', 'http://www.wikidata.org/prop/direct/P5707'), ('name', 'samples from work')]
# [('prop', 'http://www.wikidata.org/prop/direct/P1752'), ('name', 'scale')]
# [('prop', 'http://www.wikidata.org/prop/direct/P4608'), ('name', 'scenographer')]
# [('prop', 'http://www.wikidata.org/prop/direct/P5555'), ('name', 'schematic')]
# [('prop', 'http://www.wikidata.org/prop/direct/P58'), ('name', 'screenwriter')]
# [('prop', 'http://www.wikidata.org/prop/direct/P4908'), ('name', 'season')]
# [('prop', 'http://www.wikidata.org/prop/direct/P1659'), ('name', 'see also')]
# [('prop', 'http://www.wikidata.org/prop/direct/P8278'), ('name', 'serial identifier on SerialZone')]
# [('prop', 'http://www.wikidata.org/prop/direct/P1545'), ('name', 'series ordinal')]
# [('prop', 'http://www.wikidata.org/prop/direct/P2512'), ('name', 'series spin-off')]
# [('prop', 'http://www.wikidata.org/prop/direct/P9215'), ('name', 'set during recurring event')]
# [('prop', 'http://www.wikidata.org/prop/direct/P8411'), ('name', 'set in environment')]
# [('prop', 'http://www.wikidata.org/prop/direct/P2408'), ('name', 'set in period')]
# [('prop', 'http://www.wikidata.org/prop/direct/P21'), ('name', 'sex or gender')]
# [('prop', 'http://www.wikidata.org/prop/direct/P3030'), ('name', 'sheet music')]
# [('prop', 'http://www.wikidata.org/prop/direct/P1813'), ('name', 'short name')]
# [('prop', 'http://www.wikidata.org/prop/direct/P2407'), ('name', 'short-term exposure limit')]
# [('prop', 'http://www.wikidata.org/prop/direct/P793'), ('name', 'significant event')]
# [('prop', 'http://www.wikidata.org/prop/direct/P3342'), ('name', 'significant person')]
# [('prop', 'http://www.wikidata.org/prop/direct/P7340'), ('name', 'sixpackfilmdata film ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P8687'), ('name', 'social media followers')]
# [('prop', 'http://www.wikidata.org/prop/direct/P5028'), ('name', 'sound designer')]
# [('prop', 'http://www.wikidata.org/prop/direct/P406'), ('name', 'soundtrack release')]
# [('prop', 'http://www.wikidata.org/prop/direct/P1896'), ('name', 'source website for the property')]
# [('prop', 'http://www.wikidata.org/prop/direct/P989'), ('name', 'spoken text audio')]
# [('prop', 'http://www.wikidata.org/prop/direct/P859'), ('name', 'sponsor')]
# [('prop', 'http://www.wikidata.org/prop/direct/P641'), ('name', 'sport')]
# [('prop', 'http://www.wikidata.org/prop/direct/P1427'), ('name', 'start point')]
# [('prop', 'http://www.wikidata.org/prop/direct/P580'), ('name', 'start time')]
# [('prop', 'http://www.wikidata.org/prop/direct/P7512'), ('name', 'startrek.com Database ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P248'), ('name', 'stated in')]
# [('prop', 'http://www.wikidata.org/prop/direct/P805'), ('name', 'statement is subject of')]
# [('prop', 'http://www.wikidata.org/prop/direct/P3275'), ('name', 'storyboard artist')]
# [('prop', 'http://www.wikidata.org/prop/direct/P963'), ('name', 'streaming media URL')]
# [('prop', 'http://www.wikidata.org/prop/direct/P279'), ('name', 'subclass of')]
# [('prop', 'http://www.wikidata.org/prop/direct/P3984'), ('name', 'subreddit')]
# [('prop', 'http://www.wikidata.org/prop/direct/P1680'), ('name', 'subtitle')]
# [('prop', 'http://www.wikidata.org/prop/direct/P1434'), ('name', 'takes place in fictional universe')]
# [('prop', 'http://www.wikidata.org/prop/direct/P942'), ('name', 'theme music')]
# [('prop', 'http://www.wikidata.org/prop/direct/P2348'), ('name', 'time period')]
# [('prop', 'http://www.wikidata.org/prop/direct/P1476'), ('name', 'title')]
# [('prop', 'http://www.wikidata.org/prop/direct/P910'), ('name', "topic's main category")]
# [('prop', 'http://www.wikidata.org/prop/direct/P1424'), ('name', "topic's main template")]
# [('prop', 'http://www.wikidata.org/prop/direct/P2139'), ('name', 'total revenue')]
# [('prop', 'http://www.wikidata.org/prop/direct/P5051'), ('name', 'towards')]
# [('prop', 'http://www.wikidata.org/prop/direct/P658'), ('name', 'tracklist')]
# [('prop', 'http://www.wikidata.org/prop/direct/P655'), ('name', 'translator')]
# [('prop', 'http://www.wikidata.org/prop/direct/P2739'), ('name', 'typeface/font used')]
# [('prop', 'http://www.wikidata.org/prop/direct/P2737'), ('name', 'union of')]
# [('prop', 'http://www.wikidata.org/prop/direct/P366'), ('name', 'use')]
# [('prop', 'http://www.wikidata.org/prop/direct/P7261'), ('name', 'use restriction status')]
# [('prop', 'http://www.wikidata.org/prop/direct/P2283'), ('name', 'uses')]
# [('prop', 'http://www.wikidata.org/prop/direct/P9182'), ('name', 'uta-net.com song ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P8351'), ('name', 'vglist video game ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P10'), ('name', 'video')]
# [('prop', 'http://www.wikidata.org/prop/direct/P725'), ('name', 'voice actor')]
# [('prop', 'http://www.wikidata.org/prop/direct/P478'), ('name', 'volume')]
# [('prop', 'http://www.wikidata.org/prop/direct/P1019'), ('name', 'web feed URL')]
# [('prop', 'http://www.wikidata.org/prop/direct/P2049'), ('name', 'width')]
# [('prop', 'http://www.wikidata.org/prop/direct/P1346'), ('name', 'winner')]
# [('prop', 'http://www.wikidata.org/prop/direct/P2032'), ('name', 'work period (end)')]
# [('prop', 'http://www.wikidata.org/prop/direct/P2031'), ('name', 'work period (start)')]
# [('prop', 'http://www.wikidata.org/prop/direct/P9318'), ('name', 'Ávvir topic ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P2529'), ('name', 'ČSFD film ID')]
# 924

# %%
#use the property P86 to list some composers
queryString = """
SELECT DISTINCT ?obj ?name
WHERE { 
    # ?film wdt:P31 wd:Q11424;
        wdt:P86 ?obj.
    # ?obj sc:name ?name.
}
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('obj', 'http://www.wikidata.org/entity/Q11720172'), ('name', 'Janusz Grudziński')]
# [('obj', 'http://www.wikidata.org/entity/Q11767762'), ('name', 'Marcin Pospieszalski')]
# [('obj', 'http://www.wikidata.org/entity/Q11817456'), ('name', 'Piotr Figiel')]
# [('obj', 'http://www.wikidata.org/entity/Q13036911'), ('name', 'Aleksandër Lalo')]
# [('obj', 'http://www.wikidata.org/entity/Q3299298'), ('name', 'Avni Mula')]
# [('obj', 'http://www.wikidata.org/entity/Q4759658'), ('name', 'Andrzej Markowski')]
# [('obj', 'http://www.wikidata.org/entity/Q7196950'), ('name', 'Piotr Hertel')]
# [('obj', 'http://www.wikidata.org/entity/Q9285011'), ('name', 'Hajg Zaharian')]
# [('obj', 'http://www.wikidata.org/entity/Q9312585'), ('name', 'Roman Rewakowicz')]
# [('obj', 'http://www.wikidata.org/entity/Q159250'), ('name', 'Daniel Landa')]
# [('obj', 'http://www.wikidata.org/entity/Q10287874'), ('name', 'Gabriel Migliori')]
# [('obj', 'http://www.wikidata.org/entity/Q1692106'), ('name', 'Johan Zachrisson')]
# [('obj', 'http://www.wikidata.org/entity/Q10327605'), ('name', 'Mauro Senise')]
# [('obj', 'http://www.wikidata.org/entity/Q11912173'), ('name', 'Vladivojna La Chia')]
# [('obj', 'http://www.wikidata.org/entity/Q1261038'), ('name', 'Richard A. Whiting')]
# [('obj', 'http://www.wikidata.org/entity/Q1564988'), ('name', 'Radamés Gnattali')]
# [('obj', 'http://www.wikidata.org/entity/Q5248182'), ('name', 'Deborah Blando')]
# [('obj', 'http://www.wikidata.org/entity/Q5570555'), ('name', 'Tord Benner')]
# [('obj', 'http://www.wikidata.org/entity/Q5961437'), ('name', 'Lille Bror Söderlundh')]
# [('obj', 'http://www.wikidata.org/entity/Q6200457'), ('name', 'Jules Sylvain')]
# 20

# %%
# look at their occupation
queryString = """
SELECT DISTINCT ?inst ?name
WHERE { 
    # ?film wdt:P31 wd:Q11424;
        wdt:P86 ?obj.
    # ?obj wdt:P106 ?inst.
    # ?inst sc:name ?name.
    FILTER(REGEX(?name,"ompo")).
}
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('inst', 'http://www.wikidata.org/entity/Q1415090'), ('name', 'film score composer')]
# [('inst', 'http://www.wikidata.org/entity/Q36834'), ('name', 'composer')]
# [('inst', 'http://www.wikidata.org/entity/Q21680731'), ('name', 'opera composer')]
# [('inst', 'http://www.wikidata.org/entity/Q21680663'), ('name', 'classical composer')]
# [('inst', 'http://www.wikidata.org/entity/Q21680699'), ('name', 'operetta composer')]
# [('inst', 'http://www.wikidata.org/entity/Q24256060'), ('name', 'professor of music composition')]
# [('inst', 'http://www.wikidata.org/entity/Q64356038'), ('name', 'musical theatre composer')]
# [('inst', 'http://www.wikidata.org/entity/Q8008937'), ('name', 'Category:Composers')]
# [('inst', 'http://www.wikidata.org/entity/Q63536580'), ('name', 'video game composer')]
# [('inst', 'http://www.wikidata.org/entity/Q5156675'), ('name', 'Compo')]
# 10

# %%
### insert the result of TASK 2 in the file
og_uri = "http://www.wikidata.org/entity/Q36834"
og_name = "composer"
obj = {"uri":og_uri,"name":og_name}
evaluation.add_result(evaluation.get_index_workflow(pt),"2", evaluation.TYPE_SINGLE ,"uri", [obj] ,"all")
# Out:
# The index of this workflow is: 2_5
# The path is /locale/data/jupyter/prando/notebook/2022/results/workflow2_5.json
# JSON object updated

# %% [markdown]
# Find `wd:Q36834` -> composer

# %% [markdown]
# ## Task 3

# %%
# use the property genre (P136) found some queries above
queryString = """
SELECT DISTINCT ?obj ?name
WHERE { 
    # ?film wdt:P31 wd:Q11424;
        wdt:P136 ?obj.
    # ?obj sc:name ?name.
}
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('obj', 'http://www.wikidata.org/entity/Q1054574'), ('name', 'romance film')]
# [('obj', 'http://www.wikidata.org/entity/Q130232'), ('name', 'drama')]
# [('obj', 'http://www.wikidata.org/entity/Q157443'), ('name', 'comedy film')]
# [('obj', 'http://www.wikidata.org/entity/Q188473'), ('name', 'action film')]
# [('obj', 'http://www.wikidata.org/entity/Q200092'), ('name', 'horror film')]
# [('obj', 'http://www.wikidata.org/entity/Q2297927'), ('name', 'spy film')]
# [('obj', 'http://www.wikidata.org/entity/Q369747'), ('name', 'war film')]
# [('obj', 'http://www.wikidata.org/entity/Q52162262'), ('name', 'film based on literature')]
# [('obj', 'http://www.wikidata.org/entity/Q645928'), ('name', 'biographical film')]
# [('obj', 'http://www.wikidata.org/entity/Q846544'), ('name', 'disaster film')]
# [('obj', 'http://www.wikidata.org/entity/Q52207399'), ('name', 'film based on a novel')]
# [('obj', 'http://www.wikidata.org/entity/Q17013749'), ('name', 'historical film')]
# [('obj', 'http://www.wikidata.org/entity/Q1196408'), ('name', 'historical fiction')]
# [('obj', 'http://www.wikidata.org/entity/Q136472'), ('name', 'historical literature')]
# [('obj', 'http://www.wikidata.org/entity/Q2561438'), ('name', 'slice of life')]
# [('obj', 'http://www.wikidata.org/entity/Q2642760'), ('name', 'vigilante film')]
# [('obj', 'http://www.wikidata.org/entity/Q20656232'), ('name', 'science fiction action film')]
# [('obj', 'http://www.wikidata.org/entity/Q1548170'), ('name', 'musical comedy')]
# [('obj', 'http://www.wikidata.org/entity/Q193979'), ('name', 'farce')]
# [('obj', 'http://www.wikidata.org/entity/Q157394'), ('name', 'fantasy film')]
# 20

# %%
# use the property genre (P136) found some queries above and get the class
queryString = """
SELECT DISTINCT ?inst ?name
WHERE { 
    # ?film wdt:P31 wd:Q11424;
        wdt:P136 ?obj.
    # ?obj wdt:P31 ?inst.
    # ?inst sc:name ?name.
}
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('inst', 'http://www.wikidata.org/entity/Q108329096'), ('name', 'genre by art form')]
# [('inst', 'http://www.wikidata.org/entity/Q5937792'), ('name', 'crime fiction')]
# [('inst', 'http://www.wikidata.org/entity/Q201658'), ('name', 'film genre')]
# [('inst', 'http://www.wikidata.org/entity/Q1194240'), ('name', 'science fiction genre')]
# [('inst', 'http://www.wikidata.org/entity/Q223393'), ('name', 'literary genre')]
# [('inst', 'http://www.wikidata.org/entity/Q1792379'), ('name', 'art genre')]
# [('inst', 'http://www.wikidata.org/entity/Q20076756'), ('name', 'speculative fiction genre')]
# [('inst', 'http://www.wikidata.org/entity/Q108465955'), ('name', 'fiction genre')]
# [('inst', 'http://www.wikidata.org/entity/Q15961987'), ('name', 'television genre')]
# [('inst', 'http://www.wikidata.org/entity/Q7777573'), ('name', 'theatrical genre')]
# [('inst', 'http://www.wikidata.org/entity/Q5151404'), ('name', 'comedic genre')]
# [('inst', 'http://www.wikidata.org/entity/Q20656220'), ('name', 'thriller genre')]
# [('inst', 'http://www.wikidata.org/entity/Q5188177'), ('name', 'cross-genre')]
# [('inst', 'http://www.wikidata.org/entity/Q188451'), ('name', 'music genre')]
# [('inst', 'http://www.wikidata.org/entity/Q1437361'), ('name', 'form')]
# [('inst', 'http://www.wikidata.org/entity/Q759853'), ('name', 'film format')]
# [('inst', 'http://www.wikidata.org/entity/Q15961983'), ('name', 'radio genre')]
# [('inst', 'http://www.wikidata.org/entity/Q4263830'), ('name', 'literary form')]
# [('inst', 'http://www.wikidata.org/entity/Q483394'), ('name', 'genre')]
# [('inst', 'http://www.wikidata.org/entity/Q1053916'), ('name', 'theme')]
# [('inst', 'http://www.wikidata.org/entity/Q621993'), ('name', 'literary class')]
# [('inst', 'http://www.wikidata.org/entity/Q8187769'), ('name', 'economic activity')]
# [('inst', 'http://www.wikidata.org/entity/Q862597'), ('name', 'musical form')]
# [('inst', 'http://www.wikidata.org/entity/Q89362829'), ('name', 'non-music')]
# [('inst', 'http://www.wikidata.org/entity/Q108466143'), ('name', 'non-fiction genre')]
# [('inst', 'http://www.wikidata.org/entity/Q20644555'), ('name', 'fantasy genre')]
# [('inst', 'http://www.wikidata.org/entity/Q4178140'), ('name', 'anime and manga genre')]
# [('inst', 'http://www.wikidata.org/entity/Q49148153'), ('name', 'pornography genre')]
# [('inst', 'http://www.wikidata.org/entity/Q108317211'), ('name', 'novel genre')]
# [('inst', 'http://www.wikidata.org/entity/Q108368282'), ('name', 'genre by literary form')]
# [('inst', 'http://www.wikidata.org/entity/Q4167410'), ('name', 'Wikimedia disambiguation page')]
# [('inst', 'http://www.wikidata.org/entity/Q659563'), ('name', 'video game genre')]
# [('inst', 'http://www.wikidata.org/entity/Q60539481'), ('name', 'negative emotion')]
# [('inst', 'http://www.wikidata.org/entity/Q11862829'), ('name', 'academic discipline')]
# [('inst', 'http://www.wikidata.org/entity/Q2604680'), ('name', 'target audience')]
# [('inst', 'http://www.wikidata.org/entity/Q3326717'), ('name', 'literary movement')]
# [('inst', 'http://www.wikidata.org/entity/Q1415395'), ('name', 'film industry')]
# [('inst', 'http://www.wikidata.org/entity/Q31629'), ('name', 'type of sport')]
# [('inst', 'http://www.wikidata.org/entity/Q4356073'), ('name', 'spectator sport')]
# [('inst', 'http://www.wikidata.org/entity/Q9415'), ('name', 'emotion')]
# [('inst', 'http://www.wikidata.org/entity/Q1920219'), ('name', 'social issue')]
# [('inst', 'http://www.wikidata.org/entity/Q103110540'), ('name', 'anime genre')]
# [('inst', 'http://www.wikidata.org/entity/Q3516833'), ('name', 'animation technique')]
# [('inst', 'http://www.wikidata.org/entity/Q45971958'), ('name', 'performing arts genre')]
# [('inst', 'http://www.wikidata.org/entity/Q4894405'), ('name', 'journalism genre')]
# [('inst', 'http://www.wikidata.org/entity/Q1001378'), ('name', 'cinematic technique')]
# [('inst', 'http://www.wikidata.org/entity/Q5484828'), ('name', 'cyberpunk derivative form')]
# [('inst', 'http://www.wikidata.org/entity/Q101352'), ('name', 'family name')]
# [('inst', 'http://www.wikidata.org/entity/Q20643324'), ('name', 'opera genre')]
# [('inst', 'http://www.wikidata.org/entity/Q589183'), ('name', 'radio format')]
# [('inst', 'http://www.wikidata.org/entity/Q13406463'), ('name', 'Wikimedia list article')]
# [('inst', 'http://www.wikidata.org/entity/Q745775'), ('name', 'narrative mode')]
# [('inst', 'http://www.wikidata.org/entity/Q1288568'), ('name', 'modern language')]
# [('inst', 'http://www.wikidata.org/entity/Q33742'), ('name', 'natural language')]
# [('inst', 'http://www.wikidata.org/entity/Q34770'), ('name', 'language')]
# [('inst', 'http://www.wikidata.org/entity/Q152559'), ('name', 'macrolanguage')]
# [('inst', 'http://www.wikidata.org/entity/Q28640'), ('name', 'profession')]
# [('inst', 'http://www.wikidata.org/entity/Q56055944'), ('name', 'art form')]
# [('inst', 'http://www.wikidata.org/entity/Q22808320'), ('name', 'Wikimedia human name disambiguation page')]
# [('inst', 'http://www.wikidata.org/entity/Q16695773'), ('name', 'WikiProject')]
# [('inst', 'http://www.wikidata.org/entity/Q16748888'), ('name', 'advanced emotion')]
# [('inst', 'http://www.wikidata.org/entity/Q97430452'), ('name', 'performing arts industry')]
# [('inst', 'http://www.wikidata.org/entity/Q24856'), ('name', 'film series')]
# [('inst', 'http://www.wikidata.org/entity/Q1969448'), ('name', 'term')]
# [('inst', 'http://www.wikidata.org/entity/Q4671286'), ('name', 'academic major')]
# [('inst', 'http://www.wikidata.org/entity/Q36649'), ('name', 'visual art')]
# [('inst', 'http://www.wikidata.org/entity/Q11921029'), ('name', 'music style')]
# [('inst', 'http://www.wikidata.org/entity/Q107356781'), ('name', 'song type')]
# [('inst', 'http://www.wikidata.org/entity/Q506240'), ('name', 'television film')]
# [('inst', 'http://www.wikidata.org/entity/Q4220920'), ('name', 'filmmaking occupation')]
# [('inst', 'http://www.wikidata.org/entity/Q20087698'), ('name', 'comics genre')]
# [('inst', 'http://www.wikidata.org/entity/Q59126'), ('name', 'xiaoshuo')]
# [('inst', 'http://www.wikidata.org/entity/Q1126006'), ('name', 'public broadcaster')]
# [('inst', 'http://www.wikidata.org/entity/Q151885'), ('name', 'concept')]
# [('inst', 'http://www.wikidata.org/entity/Q41719'), ('name', 'hypothesis')]
# [('inst', 'http://www.wikidata.org/entity/Q1047698'), ('name', 'superpower')]
# [('inst', 'http://www.wikidata.org/entity/Q179661'), ('name', 'treatment')]
# [('inst', 'http://www.wikidata.org/entity/Q1047113'), ('name', 'specialty')]
# [('inst', 'http://www.wikidata.org/entity/Q331769'), ('name', 'mood')]
# [('inst', 'http://www.wikidata.org/entity/Q2738074'), ('name', 'political movement')]
# [('inst', 'http://www.wikidata.org/entity/Q3001152'), ('name', 'movement in cinema')]
# [('inst', 'http://www.wikidata.org/entity/Q482994'), ('name', 'album')]
# [('inst', 'http://www.wikidata.org/entity/Q2198855'), ('name', 'cultural movement')]
# [('inst', 'http://www.wikidata.org/entity/Q968159'), ('name', 'art movement')]
# [('inst', 'http://www.wikidata.org/entity/Q191328'), ('name', 'tonal language')]
# [('inst', 'http://www.wikidata.org/entity/Q3305213'), ('name', 'painting')]
# [('inst', 'http://www.wikidata.org/entity/Q9332'), ('name', 'behavior')]
# [('inst', 'http://www.wikidata.org/entity/Q108306867'), ('name', 'tone (work)')]
# [('inst', 'http://www.wikidata.org/entity/Q1149305'), ('name', 'disposition')]
# [('inst', 'http://www.wikidata.org/entity/Q622645'), ('name', 'attitude')]
# [('inst', 'http://www.wikidata.org/entity/Q19361238'), ('name', 'Wikidata metaclass')]
# [('inst', 'http://www.wikidata.org/entity/Q636497'), ('name', 'stock character')]
# [('inst', 'http://www.wikidata.org/entity/Q17305127'), ('name', 'fictional profession')]
# [('inst', 'http://www.wikidata.org/entity/Q842284'), ('name', 'skateboarding')]
# [('inst', 'http://www.wikidata.org/entity/Q5'), ('name', 'human')]
# [('inst', 'http://www.wikidata.org/entity/Q215380'), ('name', 'musical group')]
# [('inst', 'http://www.wikidata.org/entity/Q1792644'), ('name', 'art style')]
# [('inst', 'http://www.wikidata.org/entity/Q103112098'), ('name', 'manga genre')]
# [('inst', 'http://www.wikidata.org/entity/Q11424'), ('name', 'film')]
# [('inst', 'http://www.wikidata.org/entity/Q3624078'), ('name', 'sovereign state')]
# [('inst', 'http://www.wikidata.org/entity/Q4209223'), ('name', 'Rechtsstaat')]
# [('inst', 'http://www.wikidata.org/entity/Q43702'), ('name', 'federation')]
# [('inst', 'http://www.wikidata.org/entity/Q619610'), ('name', 'social state')]
# [('inst', 'http://www.wikidata.org/entity/Q63791824'), ('name', 'country bordering the Baltic Sea')]
# [('inst', 'http://www.wikidata.org/entity/Q7270'), ('name', 'republic')]
# [('inst', 'http://www.wikidata.org/entity/Q67515288'), ('name', 'cinema of country or region')]
# [('inst', 'http://www.wikidata.org/entity/Q3233738'), ('name', 'Golden age')]
# [('inst', 'http://www.wikidata.org/entity/Q576639'), ('name', 'essentially contested concept')]
# [('inst', 'http://www.wikidata.org/entity/Q107357104'), ('name', 'type of dance')]
# [('inst', 'http://www.wikidata.org/entity/Q28820001'), ('name', 'music scene')]
# [('inst', 'http://www.wikidata.org/entity/Q42907216'), ('name', 'video game theme')]
# [('inst', 'http://www.wikidata.org/entity/Q5257307'), ('name', 'prize')]
# [('inst', 'http://www.wikidata.org/entity/Q3445707'), ('name', 'tax policy')]
# [('inst', 'http://www.wikidata.org/entity/Q515244'), ('name', 'administrative procedure')]
# [('inst', 'http://www.wikidata.org/entity/Q3024240'), ('name', 'historical country')]
# [('inst', 'http://www.wikidata.org/entity/Q483677'), ('name', 'pseudoscience')]
# [('inst', 'http://www.wikidata.org/entity/Q2728698'), ('name', 'religious belief')]
# [('inst', 'http://www.wikidata.org/entity/Q170835'), ('name', 'cosmogony')]
# [('inst', 'http://www.wikidata.org/entity/Q4430243'), ('name', 'social organization')]
# [('inst', 'http://www.wikidata.org/entity/Q6055843'), ('name', 'internet genre')]
# [('inst', 'http://www.wikidata.org/entity/Q89522629'), ('name', 'poetic form')]
# [('inst', 'http://www.wikidata.org/entity/Q1406161'), ('name', 'artistic theme')]
# [('inst', 'http://www.wikidata.org/entity/Q26971562'), ('name', 'comic format')]
# [('inst', 'http://www.wikidata.org/entity/Q212434'), ('name', 'Olympic sport')]
# [('inst', 'http://www.wikidata.org/entity/Q134556'), ('name', 'single')]
# [('inst', 'http://www.wikidata.org/entity/Q6647660'), ('name', 'literary element')]
# [('inst', 'http://www.wikidata.org/entity/Q18011171'), ('name', 'unfinished or abandoned film project')]
# [('inst', 'http://www.wikidata.org/entity/Q50572323'), ('name', 'fantastic literature genre')]
# [('inst', 'http://www.wikidata.org/entity/Q15831596'), ('name', 'class of fictional entities')]
# [('inst', 'http://www.wikidata.org/entity/Q2465832'), ('name', 'branch of science')]
# [('inst', 'http://www.wikidata.org/entity/Q4502142'), ('name', 'visual artwork')]
# [('inst', 'http://www.wikidata.org/entity/Q2695280'), ('name', 'technique')]
# [('inst', 'http://www.wikidata.org/entity/Q1209283'), ('name', 'electronic media')]
# [('inst', 'http://www.wikidata.org/entity/Q20742825'), ('name', 'cultural depiction')]
# [('inst', 'http://www.wikidata.org/entity/Q264965'), ('name', 'subculture')]
# [('inst', 'http://www.wikidata.org/entity/Q19116554'), ('name', 'youth subculture')]
# [('inst', 'http://www.wikidata.org/entity/Q49447'), ('name', 'world view')]
# [('inst', 'http://www.wikidata.org/entity/Q2915955'), ('name', 'philosophical movement')]
# [('inst', 'http://www.wikidata.org/entity/Q5303685'), ('name', 'doxastic attitude')]
# [('inst', 'http://www.wikidata.org/entity/Q3377406'), ('name', 'political catch phrase')]
# [('inst', 'http://www.wikidata.org/entity/Q13442814'), ('name', 'scholarly article')]
# [('inst', 'http://www.wikidata.org/entity/Q12737077'), ('name', 'occupation')]
# 142

# %%
# film genre (wd:Q201658)
queryString = """
SELECT DISTINCT ?inst ?name
WHERE { 
    BIND(wd:Q201658 AS ?inst).
    # ?inst sc:name ?name.
}
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('inst', 'http://www.wikidata.org/entity/Q201658'), ('name', 'film genre')]
# 1

# %%
### insert the result of TASK 3 in the file
og_uri = "http://www.wikidata.org/entity/Q201658"
og_name = "film genre"
obj = {"uri":og_uri,"name":og_name}
evaluation.add_result(evaluation.get_index_workflow(pt),"3", evaluation.TYPE_SINGLE ,"uri", [obj] ,"all")
# Out:
# The index of this workflow is: 2_5
# The path is /locale/data/jupyter/prando/notebook/2022/results/workflow2_5.json
# JSON object updated

# %% [markdown]
# Found `wd:Q201658` -> film genre

# %% [markdown]
# ## Task 4

# %% [markdown]
# Need to find date of release and also the country of release

# %%
# find the date and the country
queryString = """
SELECT DISTINCT ?prop ?name
WHERE { 
    # ?film wdt:P31 wd:Q11424;
        # ?prop ?obj.
    # ?prop sc:name ?name.
    FILTER(REGEX(?name,"date") || REGEX(?name,"ountr") ).
}
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('prop', 'http://www.wikidata.org/prop/direct/P577'), ('name', 'publication date')]
# [('prop', 'http://www.wikidata.org/prop/direct/P495'), ('name', 'country of origin')]
# [('prop', 'http://www.wikidata.org/prop/direct/P17'), ('name', 'country')]
# [('prop', 'http://www.wikidata.org/prop/direct/P2754'), ('name', 'production date')]
# [('prop', 'http://www.wikidata.org/prop/direct/P3893'), ('name', 'public domain date')]
# [('prop', 'http://www.wikidata.org/prop/direct/P2913'), ('name', 'date depicted')]
# [('prop', 'http://www.wikidata.org/prop/direct/P1191'), ('name', 'date of first performance')]
# [('prop', 'http://www.wikidata.org/prop/direct/P1619'), ('name', 'date of official opening')]
# [('prop', 'http://www.wikidata.org/prop/direct/P6949'), ('name', 'announcement date')]
# [('prop', 'http://www.wikidata.org/prop/direct/P3999'), ('name', 'date of official closure')]
# [('prop', 'http://www.wikidata.org/prop/direct/P569'), ('name', 'date of birth')]
# [('prop', 'http://www.wikidata.org/prop/direct/P2960'), ('name', 'archive date')]
# [('prop', 'http://www.wikidata.org/prop/direct/P27'), ('name', 'country of citizenship')]
# [('prop', 'http://www.wikidata.org/prop/direct/P576'), ('name', 'dissolved, abolished or demolished date')]
# [('prop', 'http://www.wikidata.org/prop/direct/P5204'), ('name', 'date of commercialization')]
# [('prop', 'http://www.wikidata.org/prop/direct/P570'), ('name', 'date of death')]
# 16

# %%
# use the property publication date and country of origin. But first need to find United States
queryString = """
SELECT DISTINCT ?obj ?name
WHERE { 
    # ?film wdt:P31 wd:Q11424;
        wdt:P495 ?obj.
    # ?obj sc:name ?name.
    FILTER(REGEX(?name,"[U,u]")).
}
ORDER BY DESC (?name)
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('obj', 'http://www.wikidata.org/entity/Q42537'), ('name', 'flag of the United States')]
# [('obj', 'http://www.wikidata.org/entity/Q165230'), ('name', 'flag of the Soviet Union')]
# [('obj', 'http://www.wikidata.org/entity/Q380675'), ('name', 'cinema of the United States')]
# [('obj', 'http://www.wikidata.org/entity/Q36704'), ('name', 'Yugoslavia')]
# [('obj', 'http://www.wikidata.org/entity/Q41304'), ('name', 'Weimar Republic')]
# [('obj', 'http://www.wikidata.org/entity/Q717'), ('name', 'Venezuela')]
# [('obj', 'http://www.wikidata.org/entity/Q265'), ('name', 'Uzbekistan')]
# [('obj', 'http://www.wikidata.org/entity/Q77'), ('name', 'Uruguay')]
# [('obj', 'http://www.wikidata.org/entity/Q30'), ('name', 'United States of America')]
# [('obj', 'http://www.wikidata.org/entity/Q174193'), ('name', 'United Kingdom of Great Britain and Ireland')]
# [('obj', 'http://www.wikidata.org/entity/Q145'), ('name', 'United Kingdom')]
# [('obj', 'http://www.wikidata.org/entity/Q170468'), ('name', 'United Arab Republic')]
# [('obj', 'http://www.wikidata.org/entity/Q878'), ('name', 'United Arab Emirates')]
# [('obj', 'http://www.wikidata.org/entity/Q193619'), ('name', 'Union of South Africa')]
# [('obj', 'http://www.wikidata.org/entity/Q27190661'), ('name', 'Umoma')]
# [('obj', 'http://www.wikidata.org/entity/Q133356'), ('name', 'Ukrainian Soviet Socialist Republic')]
# [('obj', 'http://www.wikidata.org/entity/Q243610'), ('name', "Ukrainian People's Republic")]
# [('obj', 'http://www.wikidata.org/entity/Q212'), ('name', 'Ukraine')]
# [('obj', 'http://www.wikidata.org/entity/Q1036'), ('name', 'Uganda')]
# [('obj', 'http://www.wikidata.org/entity/Q874'), ('name', 'Turkmenistan')]
# 20

# %%
# use the property publication date and country of origin. USA (Q30)
queryString = """
SELECT DISTINCT ?genre ?name COUNT(DISTINCT ?film) AS ?counts
WHERE { 
    # ?film wdt:P31 wd:Q11424;
        wdt:P495 wd:Q30;
        wdt:P136 ?genre;
        wdt:P577 ?date.
    # ?genre wdt:P31 wd:Q201658.
    FILTER ( isLiteral(?date) ) .
    FILTER(?date>=xsd:date("2010-01-01") && ?date<xsd:date("2016-01-01")).
    # ?genre sc:name ?name.
}
GROUP BY ?genre ?name
ORDER BY DESC (?counts)
LIMIT 10
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('genre', 'http://www.wikidata.org/entity/Q93204'), ('name', 'documentary film'), ('counts', '1648')]
# [('genre', 'http://www.wikidata.org/entity/Q130232'), ('name', 'drama'), ('counts', '1584')]
# [('genre', 'http://www.wikidata.org/entity/Q157443'), ('name', 'comedy film'), ('counts', '687')]
# [('genre', 'http://www.wikidata.org/entity/Q200092'), ('name', 'horror film'), ('counts', '663')]
# [('genre', 'http://www.wikidata.org/entity/Q188473'), ('name', 'action film'), ('counts', '573')]
# [('genre', 'http://www.wikidata.org/entity/Q2484376'), ('name', 'thriller film'), ('counts', '521')]
# [('genre', 'http://www.wikidata.org/entity/Q471839'), ('name', 'science fiction film'), ('counts', '318')]
# [('genre', 'http://www.wikidata.org/entity/Q20442589'), ('name', 'LGBT-related film'), ('counts', '311')]
# [('genre', 'http://www.wikidata.org/entity/Q859369'), ('name', 'comedy-drama'), ('counts', '290')]
# [('genre', 'http://www.wikidata.org/entity/Q959790'), ('name', 'crime film'), ('counts', '288')]
# 10

# %%
# use the property publication date and country of origin. USA (Q30)
queryString = """
SELECT DISTINCT ?genre ?name COUNT(DISTINCT ?film) AS ?counts
WHERE { 
    # ?film wdt:P31 wd:Q11424;
        wdt:P495 wd:Q30;
        wdt:P136 ?genre;
        wdt:P577 ?date.
    # ?genre wdt:P31 wd:Q201658.
    FILTER ( isLiteral(?date) ) .
    FILTER(?date>=xsd:date("1960-01-01") && ?date<xsd:date("1965-01-01")).
    # ?genre sc:name ?name.
}
GROUP BY ?genre ?name
ORDER BY DESC (?counts)
LIMIT 10
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('genre', 'http://www.wikidata.org/entity/Q130232'), ('name', 'drama'), ('counts', '339')]
# [('genre', 'http://www.wikidata.org/entity/Q157443'), ('name', 'comedy film'), ('counts', '124')]
# [('genre', 'http://www.wikidata.org/entity/Q200092'), ('name', 'horror film'), ('counts', '81')]
# [('genre', 'http://www.wikidata.org/entity/Q860626'), ('name', 'romantic comedy'), ('counts', '81')]
# [('genre', 'http://www.wikidata.org/entity/Q172980'), ('name', 'Western film'), ('counts', '77')]
# [('genre', 'http://www.wikidata.org/entity/Q369747'), ('name', 'war film'), ('counts', '71')]
# [('genre', 'http://www.wikidata.org/entity/Q842256'), ('name', 'musical film'), ('counts', '66')]
# [('genre', 'http://www.wikidata.org/entity/Q471839'), ('name', 'science fiction film'), ('counts', '58')]
# [('genre', 'http://www.wikidata.org/entity/Q959790'), ('name', 'crime film'), ('counts', '52')]
# [('genre', 'http://www.wikidata.org/entity/Q1054574'), ('name', 'romance film'), ('counts', '50')]
# 10

# %%
## single literal associated to an URI
objs = []
for i in x:
    f_uri = i[0][1]
    f_name = i[1][1]
    val = i[2][1]
    obj = {}
    obj["refers_to"] = f_uri
    obj["refers_to_name"] = f_name
    obj["check"] = "value"
    obj["value"]= val
    objs.append(obj)
evaluation.add_result(evaluation.get_index_workflow(pt),"4", evaluation.TYPE_REFERRED ,"value", objs)
# Out:
# The index of this workflow is: 2_5
# The path is /locale/data/jupyter/prando/notebook/2022/results/workflow2_5.json
# JSON object updated

# %% [markdown]
# ## Task 5

# %%
# look at the year
queryString = """
SELECT DISTINCT(YEAR(?date)) AS ?max_year
WHERE {
   # ?film wdt:P577 ?date ;
         wdt:P136 ?genre .
   # ?genre wdt:P31 wd:Q201658 .
   FILTER(isLiteral(?date)).
   FILTER(?date >="2018-01-01T00:00:00Z"^^xsd:dateTime)
}
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('max_year', '2018')]
# [('max_year', '2019')]
# [('max_year', '2021')]
# [('max_year', '2020')]
# [('max_year', '2022')]
# [('max_year', '2023')]
# [('max_year', '2115')]
# [('max_year', '2040')]
# [('max_year', '2100')]
# [('max_year', '2024')]
# [('max_year', '2188')]
# 11

# %%
# find all the genres from 2001 to now that have more than 50 films for each year
# we consider films publicated up to 2021 given that the instance of Wikidata is from 2021
queryString = """
SELECT ?genre ?g_name 
WHERE{
    
    {
        SELECT DISTINCT ?genre YEAR(?date) AS ?year (COUNT(?film) AS ?films)
        WHERE {
           # ?film wdt:P577 ?date ;
                 wdt:P136 ?genre .
           # ?genre wdt:P31 wd:Q201658 .
           FILTER(?date >="2001-01-01T00:00:00Z"^^xsd:dateTime && ?date <="2022-01-01T00:00:00Z"^^xsd:dateTime)
        }
        GROUP BY ?genre YEAR(?date)
    }
    # ?genre sc:name ?g_name .
    FILTER (?films > 50)
}
GROUP BY ?genre ?g_name
HAVING (COUNT(DISTINCT ?year) >20)
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('genre', 'http://www.wikidata.org/entity/Q2484376'), ('g_name', 'thriller film')]
# [('genre', 'http://www.wikidata.org/entity/Q959790'), ('g_name', 'crime film')]
# [('genre', 'http://www.wikidata.org/entity/Q93204'), ('g_name', 'documentary film')]
# [('genre', 'http://www.wikidata.org/entity/Q188473'), ('g_name', 'action film')]
# [('genre', 'http://www.wikidata.org/entity/Q157443'), ('g_name', 'comedy film')]
# [('genre', 'http://www.wikidata.org/entity/Q130232'), ('g_name', 'drama')]
# [('genre', 'http://www.wikidata.org/entity/Q319221'), ('g_name', 'adventure film')]
# [('genre', 'http://www.wikidata.org/entity/Q200092'), ('g_name', 'horror film')]
# 8

# %%
obj = [{"uri":r[0][1],"name":r[1][1]} for r in x]
evaluation.add_result(evaluation.get_index_workflow(pt),"5", evaluation.TYPE_SET ,"uri", obj)
# Out:
# The index of this workflow is: 2_5
# The path is /locale/data/jupyter/prando/notebook/2022/results/workflow2_5.json
# JSON object updated

# %% [markdown]
# ## Task 6

# %%
# find top-10 composers of western films
queryString = """
SELECT DISTINCT ?country ?name COUNT(DISTINCT ?film) AS ?counts
WHERE { 
    # ?film wdt:P31 wd:Q11424;
        wdt:P86 ?composer;
        wdt:P136 wd:Q172980.
    # ?composer wdt:P27 ?country.
    # ?country sc:name ?name.
}
GROUP BY ?country ?name
ORDER BY DESC (?counts)
LIMIT 10
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('country', 'http://www.wikidata.org/entity/Q30'), ('name', 'United States of America'), ('counts', '1024')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('name', 'United Kingdom'), ('counts', '54')]
# [('country', 'http://www.wikidata.org/entity/Q34266'), ('name', 'Russian Empire'), ('counts', '45')]
# [('country', 'http://www.wikidata.org/entity/Q38'), ('name', 'Italy'), ('counts', '40')]
# [('country', 'http://www.wikidata.org/entity/Q183'), ('name', 'Germany'), ('counts', '38')]
# [('country', 'http://www.wikidata.org/entity/Q40'), ('name', 'Austria'), ('counts', '36')]
# [('country', 'http://www.wikidata.org/entity/Q15180'), ('name', 'Soviet Union'), ('counts', '36')]
# [('country', 'http://www.wikidata.org/entity/Q28513'), ('name', 'Austria-Hungary'), ('counts', '31')]
# [('country', 'http://www.wikidata.org/entity/Q172579'), ('name', 'Kingdom of Italy'), ('counts', '31')]
# [('country', 'http://www.wikidata.org/entity/Q142'), ('name', 'France'), ('counts', '20')]
# 10

# %%
## single literal associated to an URI
objs = []
for i in x:
    f_uri = i[0][1]
    f_name = i[1][1]
    val = i[2][1]
    obj = {}
    obj["refers_to"] = f_uri
    obj["refers_to_name"] = f_name
    obj["check"] = "value"
    obj["value"]= val
    objs.append(obj)
evaluation.add_result(evaluation.get_index_workflow(pt),"6", evaluation.TYPE_REFERRED ,"value", objs)
# Out:
# The index of this workflow is: 2_5
# The path is /locale/data/jupyter/prando/notebook/2022/results/workflow2_5.json
# JSON object updated

# %% [markdown]
# ## Task 7

# %%
# compare the decades
queryString = """
SELECT COUNT(DISTINCT ?film) AS ?counts
WHERE { 
    # ?film wdt:P136 wd:Q172980 ;
        wdt:P31 wd:Q11424;
        wdt:P577 ?date.
    FILTER(?date>=xsd:date("1961-01-01") && ?date<xsd:date("1971-01-01")).
}
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('counts', '265')]
# 1

# %%
# compare the decades
queryString = """
SELECT COUNT(DISTINCT ?film) AS ?counts
WHERE { 
    # ?film wdt:P136 wd:Q172980 ;
        wdt:P31 wd:Q11424;
        wdt:P577 ?date.
    FILTER(?date>=xsd:date("2001-01-01") && ?date<xsd:date("2011-01-01")).
}
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('counts', '65')]
# 1

# %%
# find n_western films between 1961-1970 and 2001-2010 
queryString = """
SELECT DISTINCT ?decade (COUNT( DISTINCT ?film) AS ?films)
        WHERE {
           # ?film wdt:P136 wd:Q172980 ;
                 wdt:P31 wd:Q11424 ;
                 wdt:P577 ?date .
           FILTER((YEAR(?date) > 1960 && YEAR(?date) <= 1970) || (YEAR(?date) > 2000 && YEAR(?date) <= 2010))
           BIND (if(YEAR(?date) > 1960 && YEAR(?date) <= 1970,"1961-1970", "2001-2010") AS ?decade)
        }
        GROUP BY ?decade
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('decade', '2001-2010'), ('films', '64')]
# [('decade', '1961-1970'), ('films', '250')]
# 2

# %% [markdown]
# ### Task 8

# %%
# find average cast members size for western films between 1961-1970 and 2001-2010
queryString = """
SELECT DISTINCT ?decade (AVG(?cast_size) AS ?avg_cast)
WHERE {
    {
        SELECT DISTINCT ?decade ?film (COUNT(?cast) AS ?cast_size)
        WHERE {
           # ?film wdt:P136 wd:Q172980 ;
                 wdt:P31 wd:Q11424 ;
                 wdt:P577 ?date ;
                 wdt:P161 ?cast .
           FILTER((YEAR(?date) > 1960 && YEAR(?date) <= 1970) || (YEAR(?date) > 2000 && YEAR(?date) <= 2010))
           BIND (if(YEAR(?date) > 1960 && YEAR(?date) <= 1970,"1961-1970","2001-2010") AS ?decade)
        }
    }
}
GROUP BY ?decade
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('decade', '2001-2010'), ('avg_cast', '12.272727272727273')]
# [('decade', '1961-1970'), ('avg_cast', '13.259414225941423')]
# 2

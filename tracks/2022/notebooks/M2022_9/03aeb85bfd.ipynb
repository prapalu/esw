# %% [markdown]
# # General instructions
#
# The goal of the project is to materialize a set of **exploratory workloads** over a real-world, large-scale,  open-domain KG: [WikiData](https://www.wikidata.org/wiki/Wikidata:Main_Page)
#
# An exploratory workload  is composed by a set of queries, where each query is related to the information obtained previously.
#
# An exploratory workload starts with a usually vague, open ended question, and does not assume the person issuing the workload has a clear understanding of the data contained in the target database or its structure.
#
# Remeber that:
#
# 1. All the queries must run in the python notebook
# 2. You can use classes and properties only if you find them via a SPARQL query that must be present in the notebook
# 3. You do not delete useless queries. Keep everything that is synthatically valid
#
# ```
# ?p <http://schema.org/name> ?name .
# ```
#
#     is the BGP returning a human-readable name of a property or a class in Wikidata.

# %%
## SETUP used later

from SPARQLWrapper import SPARQLWrapper, JSON


prefixString = """
##-03aeb85bfd-##
PREFIX wd: <http://www.wikidata.org/entity/> 
PREFIX wdt: <http://www.wikidata.org/prop/direct/> 
PREFIX sc: <http://schema.org/>
"""

# select and construct queries
def run_query(queryString,verbose = True):
    to_run = prefixString + "\n" + queryString

    sparql = SPARQLWrapper("http://a256-gc1-03.srv.aau.dk:5820/sparql")
    sparql.setTimeout(300)
    sparql.setReturnFormat(JSON)
    sparql.setQuery(to_run)

    try :
        results = sparql.query()
        json_results = results.convert()
        if len(json_results['results']['bindings'])==0:
            print("Empty")
            return []
        array = []
        for bindings in json_results['results']['bindings']:
            app =  [ (var, value['value'])  for var, value in bindings.items() ] 
            if verbose:
                print( app)
            array.append(app)
        if verbose:
            print(len(array))
        return array

    except Exception as e :
        print("The operation failed", e)
    
# ASk queries
def run_ask_query(queryString):
    to_run = prefixString + "\n" + queryString

    sparql = SPARQLWrapper("http://a256-gc1-03.srv.aau.dk:5820/sparql")
    sparql.setTimeout(300)
    sparql.setReturnFormat(JSON)
    sparql.setQuery(to_run)

    try :
        return sparql.query().convert()

    except Exception as e :
        print("The operation failed", e)

# %% [markdown]
# # Movie Workflow Series ("Production company explorative search")
#
# Consider the following exploratory information need:
#
# > investigate the main companies working on cinema-related content. We want to know which are the main television production companies and the film production companies, which company distributes more film and some consideration about awards.

# %% [markdown]
# ## Useful URIs for the current workflow
# The following are given:
#
# | IRI           | Description   | Role      |
# | -----------   | -----------   |-----------|
# | `wdt:P1647`   | subproperty   | predicate |
# | `wdt:P31`     | instance of   | predicate |
# | `wdt:P106`    | profession    | predicate |
# | `wdt:P279`    | subclass      | predicate |
# | `wdt:P27`     | nationality   | predicate |
# | `wdt:P106`     | profession   | predicate |
# | `wd:Q5`| Human       | node |
# | `wd:Q36479`    | The Lion King      | node |

# %% [markdown]
# Also consider
#
# ```
# wd:Q36479 ?p ?obj .
# ```
#
# is the BGP to retrieve all **properties of The Lion King**
#
# Please consider that when you return a resource, you should return the IRI and the label of the resource. In particular, when the task require you to identify a BGP the result set must always be a list of couples IRI - label.
#
# The workload should:
#
#
# 1. Identify the BGP for films
#
# 2. Identify the BGP for Netflix
#
# 3. Identify the BGP for television production company
#
# 4. Identify the BGP for film production company
#
# 5. Find the top-5 companies (amongst television production company and film production company) which produced the highest number of crime films (the result set must be a list of triples company IRI, label and #crime film).
#
# 6. Find the company (amongst television production company and film production company) which distributed more films (of any kind of film genre) that they did not produce (the result set must be a list of triples company IRI, label and #film).
#
# 7. Find how many company are listed in every stock exchange market (the result set must be a list of triples stock exchange IRI, label and #companies).
#
# 8. Identify the BGP for Academy Award
#
# 9. Find the companies (among television and film production companies) that won at least 5 Academy Awards for Best Actress for the movies they produced (the result set must be a list of triples company IRI, label and #awards).

# %% [markdown]
# ## Task 1
# Identify the BGP for films

# %%
# query example
queryString = """
SELECT DISTINCT ?p ?getname
WHERE {
   # bind something
   wd:Q36479 ?p ?obj .
   #get the label
   # ?p sc:name ?getname.

}
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('get', 'http://www.wikidata.org/prop/direct/P3092'), ('getname', 'film crew member')]
# [('get', 'http://www.wikidata.org/prop/direct/P4021'), ('getname', 'danskefilm animated film ID')]
# [('get', 'http://www.wikidata.org/prop/direct/P7679'), ('getname', 'Cinépolis KLIC ID')]
# [('get', 'http://www.wikidata.org/prop/direct/P1015'), ('getname', 'NORAF ID')]
# [('get', 'http://www.wikidata.org/prop/direct/P1040'), ('getname', 'film editor')]
# [('get', 'http://www.wikidata.org/prop/direct/P1237'), ('getname', 'Box Office Mojo film ID (former scheme)')]
# [('get', 'http://www.wikidata.org/prop/direct/P1258'), ('getname', 'Rotten Tomatoes ID')]
# [('get', 'http://www.wikidata.org/prop/direct/P1265'), ('getname', 'AlloCiné film ID')]
# [('get', 'http://www.wikidata.org/prop/direct/P1273'), ('getname', 'CANTIC ID')]
# [('get', 'http://www.wikidata.org/prop/direct/P136'), ('getname', 'genre')]
# [('get', 'http://www.wikidata.org/prop/direct/P1411'), ('getname', 'nominated for')]
# [('get', 'http://www.wikidata.org/prop/direct/P1417'), ('getname', 'Encyclopædia Britannica Online ID')]
# [('get', 'http://www.wikidata.org/prop/direct/P1434'), ('getname', 'takes place in fictional universe')]
# [('get', 'http://www.wikidata.org/prop/direct/P144'), ('getname', 'based on')]
# [('get', 'http://www.wikidata.org/prop/direct/P1476'), ('getname', 'title')]
# [('get', 'http://www.wikidata.org/prop/direct/P154'), ('getname', 'logo image')]
# [('get', 'http://www.wikidata.org/prop/direct/P1552'), ('getname', 'has quality')]
# [('get', 'http://www.wikidata.org/prop/direct/P156'), ('getname', 'followed by')]
# [('get', 'http://www.wikidata.org/prop/direct/P1562'), ('getname', 'AllMovie title ID')]
# [('get', 'http://www.wikidata.org/prop/direct/P162'), ('getname', 'producer')]
# 20

# %% [markdown]
# Final query for this task

# %%
#[('get', 'http://www.wikidata.org/prop/direct/P136'), ('getname', 'genre')]
queryString = """
SELECT DISTINCT ?p ?getname
WHERE {
   # bind something
   wd:Q36479 wdt:P136 ?p.
   #get the label
   # ?p sc:name ?getname.

}
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/entity/Q2143665'), ('getname', "children's film")]
# [('p', 'http://www.wikidata.org/entity/Q130232'), ('getname', 'drama')]
# [('p', 'http://www.wikidata.org/entity/Q842256'), ('getname', 'musical film')]
# [('p', 'http://www.wikidata.org/entity/Q28968511'), ('getname', 'traditionally animated film')]
# 4

# %%
#[('get', 'http://www.wikidata.org/prop/direct/P136'), ('getname', 'genre')]
#[('p', 'http://www.wikidata.org/entity/Q28968511'), ('getname', 'traditionally animated film')]
queryString = """
SELECT DISTINCT ?p ?getname
WHERE {
   # bind something
   wd:Q28968511 ?obj ?p.
   #get the label
   # ?p sc:name ?getname.

}
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/entity/Q17175676'), ('getname', 'animated cartoon')]
# [('p', 'http://www.wikidata.org/entity/Q201658'), ('getname', 'film genre')]
# [('p', 'http://www.wikidata.org/entity/Q11425'), ('getname', 'animation')]
# [('p', 'http://www.wikidata.org/entity/Q202866'), ('getname', 'animated film')]
# [('p', 'http://www.wikidata.org/entity/Q184781'), ('getname', 'traditional animation')]
# [('p', 'http://www.wikidata.org/entity/Q6643876'), ('getname', 'list of traditionally animated feature films')]
# 6

# %%
#[('p', 'http://www.wikidata.org/entity/Q28968511'), ('getname', 'traditionally animated film')]
#[('p', 'http://www.wikidata.org/entity/Q842256'), ('getname', 'musical film')]
queryString = """
SELECT DISTINCT ?p ?getname
WHERE {
   # bind something
   wd:Q842256 ?p ?obj.
   #get the label
   # ?p sc:name ?getname.

}
LIMIT 50
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P1225'), ('getname', 'U.S. National Archives Identifier')]
# [('p', 'http://www.wikidata.org/prop/direct/P1417'), ('getname', 'Encyclopædia Britannica Online ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1889'), ('getname', 'different from')]
# [('p', 'http://www.wikidata.org/prop/direct/P227'), ('getname', 'GND ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2347'), ('getname', 'YSO ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2354'), ('getname', 'has list')]
# [('p', 'http://www.wikidata.org/prop/direct/P244'), ('getname', 'Library of Congress authority ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P268'), ('getname', 'Bibliothèque nationale de France ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('getname', 'subclass of')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('getname', 'instance of')]
# [('p', 'http://www.wikidata.org/prop/direct/P3219'), ('getname', 'Encyclopædia Universalis ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3417'), ('getname', 'Quora topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P349'), ('getname', 'National Diet Library ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3553'), ('getname', 'Zhihu topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P373'), ('getname', 'Commons category')]
# [('p', 'http://www.wikidata.org/prop/direct/P4953'), ('getname', 'Library of Congress Genre/Form Terms ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P508'), ('getname', 'BNCF Thesaurus ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P646'), ('getname', 'Freebase ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7033'), ('getname', 'Australian Educational Vocabulary ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8408'), ('getname', 'KBpedia ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P910'), ('getname', "topic's main category")]
# [('p', 'http://www.wikidata.org/prop/direct/P9318'), ('getname', 'Ávvir topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P9545'), ('getname', 'Encyclopedia of China Online Database ID')]
# 23

# %% [markdown]
# ## Task 2
# Identify the BGP for Netflix

# %%
#[('p', 'http://www.wikidata.org/prop/direct/P227'), ('getname', 'GND ID')]
queryString = """
SELECT DISTINCT ?p ?getname
WHERE {
   # bind something
   # ?p wdt:P227 ?i.
   #get the label
   # ?p sc:name ?getname.
   FILTER(REGEX(?getname, "Netflix"^^xsd:string))

}
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/entity/Q907311'), ('getname', 'Netflix')]
# 1

# %%
#[('p', 'http://www.wikidata.org/entity/Q907311'), ('getname', 'Netflix')]
queryString = """
SELECT DISTINCT ?p ?as ?i ?op
WHERE {
   # bind something
   wd:Q907311 ?p ?i.
   #get the label
   # ?p sc:name ?as.
   # ?i sc:name ?op
   
   

}
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('as', 'instance of'), ('i', 'http://www.wikidata.org/entity/Q10689397'), ('op', 'television production company')]
# [('p', 'http://www.wikidata.org/prop/direct/P400'), ('as', 'platform'), ('i', 'http://www.wikidata.org/entity/Q23930024'), ('op', 'streaming media receiver')]
# [('p', 'http://www.wikidata.org/prop/direct/P166'), ('as', 'award received'), ('i', 'http://www.wikidata.org/entity/Q838121'), ('op', 'Peabody Awards')]
# [('p', 'http://www.wikidata.org/prop/direct/P127'), ('as', 'owned by'), ('i', 'http://www.wikidata.org/entity/Q849363'), ('op', 'The Vanguard Group')]
# [('p', 'http://www.wikidata.org/prop/direct/P1056'), ('as', 'product or material produced'), ('i', 'http://www.wikidata.org/entity/Q220499'), ('op', 'streaming media')]
# [('p', 'http://www.wikidata.org/prop/direct/P452'), ('as', 'industry'), ('i', 'http://www.wikidata.org/entity/Q220499'), ('op', 'streaming media')]
# [('p', 'http://www.wikidata.org/prop/direct/P400'), ('as', 'platform'), ('i', 'http://www.wikidata.org/entity/Q842729'), ('op', 'set-top box')]
# [('p', 'http://www.wikidata.org/prop/direct/P407'), ('as', 'language of work or name'), ('i', 'http://www.wikidata.org/entity/Q20923490'), ('op', 'multiple languages')]
# [('p', 'http://www.wikidata.org/prop/direct/P127'), ('as', 'owned by'), ('i', 'http://www.wikidata.org/entity/Q219635'), ('op', 'BlackRock')]
# [('p', 'http://www.wikidata.org/prop/direct/P17'), ('as', 'country'), ('i', 'http://www.wikidata.org/entity/Q30'), ('op', 'United States of America')]
# [('p', 'http://www.wikidata.org/prop/direct/P463'), ('as', 'member of'), ('i', 'http://www.wikidata.org/entity/Q37033'), ('op', 'World Wide Web Consortium')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('as', 'instance of'), ('i', 'http://www.wikidata.org/entity/Q4830453'), ('op', 'business')]
# [('p', 'http://www.wikidata.org/prop/direct/P127'), ('as', 'owned by'), ('i', 'http://www.wikidata.org/entity/Q505275'), ('op', 'Capital Group Companies')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('as', 'instance of'), ('i', 'http://www.wikidata.org/entity/Q723685'), ('op', 'video on demand')]
# [('p', 'http://www.wikidata.org/prop/direct/P414'), ('as', 'stock exchange'), ('i', 'http://www.wikidata.org/entity/Q82059'), ('op', 'NASDAQ')]
# [('p', 'http://www.wikidata.org/prop/direct/P463'), ('as', 'member of'), ('i', 'http://www.wikidata.org/entity/Q858851'), ('op', 'Linux Foundation')]
# [('p', 'http://www.wikidata.org/prop/direct/P1454'), ('as', 'legal form'), ('i', 'http://www.wikidata.org/entity/Q891723'), ('op', 'public company')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('as', 'instance of'), ('i', 'http://www.wikidata.org/entity/Q891723'), ('op', 'public company')]
# [('p', 'http://www.wikidata.org/prop/direct/P463'), ('as', 'member of'), ('i', 'http://www.wikidata.org/entity/Q20947086'), ('op', 'Alliance for Open Media')]
# [('p', 'http://www.wikidata.org/prop/direct/P361'), ('as', 'part of'), ('i', 'http://www.wikidata.org/entity/Q507306'), ('op', 'NASDAQ-100')]
# 20

# %% [markdown]
# Final query for this task

# %% [markdown]
# ## Task 3
# Identify the BGP for television production company

# %%
#[('p', 'http://www.wikidata.org/prop/direct/P31'), ('as', 'instance of'), ('i', 'http://www.wikidata.org/entity/Q10689397'), ('op', 'television production company')]
#[('p', 'http://www.wikidata.org/entity/Q907311'), ('getname', 'Netflix')]
queryString = """
SELECT DISTINCT ?p ?as ?i ?op
WHERE {
   # bind something
   wd:Q1068 ?p ?i.
   #get the label
   # ?p sc:name ?as.
   # ?i sc:name ?op
   
   

}
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('as', 'subclass of'), ('i', 'http://www.wikidata.org/entity/Q1762059'), ('op', 'film production company')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('as', 'subclass of'), ('i', 'http://www.wikidata.org/entity/Q19364326'), ('op', 'media studio facility')]
# [('p', 'http://www.wikidata.org/prop/direct/P452'), ('as', 'industry'), ('i', 'http://www.wikidata.org/entity/Q1407228'), ('op', 'television production')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('as', 'subclass of'), ('i', 'http://www.wikidata.org/entity/Q11396960'), ('op', 'production company')]
# [('p', 'http://www.wikidata.org/prop/direct/P910'), ('as', "topic's main category"), ('i', 'http://www.wikidata.org/entity/Q8836004'), ('op', 'Category:Television production companies')]
# 5

# %% [markdown]
# Final query for this task

# %%
# write your final query#[('p', 'http://www.wikidata.org/prop/direct/P31'), ('as', 'instance of'), ('i', 'http://www.wikidata.org/entity/Q10689397'), ('op', 'television production company')]
#[('p', 'http://www.wikidata.org/entity/Q907311'), ('getname', 'Netflix')]
queryString = """
SELECT DISTINCT ?p ?as ?i ?op
WHERE {
   # bind something
   wd:Q10689397 ?p ?i.
   #get the label
   # ?p sc:name ?as.
   # ?i sc:name ?op
   
   

}
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('as', 'subclass of'), ('i', 'http://www.wikidata.org/entity/Q1762059'), ('op', 'film production company')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('as', 'subclass of'), ('i', 'http://www.wikidata.org/entity/Q19364326'), ('op', 'media studio facility')]
# [('p', 'http://www.wikidata.org/prop/direct/P452'), ('as', 'industry'), ('i', 'http://www.wikidata.org/entity/Q1407228'), ('op', 'television production')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('as', 'subclass of'), ('i', 'http://www.wikidata.org/entity/Q11396960'), ('op', 'production company')]
# [('p', 'http://www.wikidata.org/prop/direct/P910'), ('as', "topic's main category"), ('i', 'http://www.wikidata.org/entity/Q8836004'), ('op', 'Category:Television production companies')]
# 5

# %% [markdown]
# ## Task 4
# Identify the BGP for film production company

# %%
#[('p', 'http://www.wikidata.org/prop/direct/P279'), ('as', 'subclass of'), ('i', 'http://www.wikidata.org/entity/Q1762059'), ('op', 'film production company')]
queryString = """
SELECT DISTINCT ?p ?as ?i ?op
WHERE {
   # bind something
   wd:Q1762059 ?p ?i.
   #get the label
   # ?p sc:name ?as.
   # ?i sc:name ?op
   
   

}
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P1889'), ('as', 'different from'), ('i', 'http://www.wikidata.org/entity/Q375336'), ('op', 'film studio')]
# [('p', 'http://www.wikidata.org/prop/direct/P452'), ('as', 'industry'), ('i', 'http://www.wikidata.org/entity/Q1415395'), ('op', 'film industry')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('as', 'subclass of'), ('i', 'http://www.wikidata.org/entity/Q104649845'), ('op', 'film organization')]
# [('p', 'http://www.wikidata.org/prop/direct/P361'), ('as', 'part of'), ('i', 'http://www.wikidata.org/entity/Q625568'), ('op', 'show business')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('as', 'subclass of'), ('i', 'http://www.wikidata.org/entity/Q11396960'), ('op', 'production company')]
# [('p', 'http://www.wikidata.org/prop/direct/P910'), ('as', "topic's main category"), ('i', 'http://www.wikidata.org/entity/Q6483398'), ('op', 'Category:Film production companies')]
# 6

# %% [markdown]
# Final query for this task

# %%
# write your final qu#[('p', 'http://www.wikidata.org/prop/direct/P279'), ('as', 'subclass of'), ('i', 'http://www.wikidata.org/entity/Q1762059'), ('op', 'film production company')]
queryString = """
SELECT DISTINCT ?p ?as ?i ?op
WHERE {
   # bind something
   wd:Q1762059 ?p ?i.
   #get the label
   # ?p sc:name ?as.
   # ?i sc:name ?op
   
   

}
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P1889'), ('as', 'different from'), ('i', 'http://www.wikidata.org/entity/Q375336'), ('op', 'film studio')]
# [('p', 'http://www.wikidata.org/prop/direct/P452'), ('as', 'industry'), ('i', 'http://www.wikidata.org/entity/Q1415395'), ('op', 'film industry')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('as', 'subclass of'), ('i', 'http://www.wikidata.org/entity/Q104649845'), ('op', 'film organization')]
# [('p', 'http://www.wikidata.org/prop/direct/P361'), ('as', 'part of'), ('i', 'http://www.wikidata.org/entity/Q625568'), ('op', 'show business')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('as', 'subclass of'), ('i', 'http://www.wikidata.org/entity/Q11396960'), ('op', 'production company')]
# [('p', 'http://www.wikidata.org/prop/direct/P910'), ('as', "topic's main category"), ('i', 'http://www.wikidata.org/entity/Q6483398'), ('op', 'Category:Film production companies')]
# 6

# %% [markdown]
# ## Task 5
# Find the top-5 companies (amongst television production company and film production company) which produced the highest number of crime films (the result set must be a list of triples company IRI, label and #crime film).

# %%
#[('get', 'http://www.wikidata.org/prop/direct/P136'), ('getname', 'genre')]
queryString = """
SELECT DISTINCT ?p ?obj ?top ?films
WHERE {
   # bind something
   # ?p wdt:P136 ?obj.
   #get the label
   # ?p sc:name ?top.
   # ?obj sc:name ?films
   FILTER(REGEX(?films,"crime film"^^xsd:string ))

}
LIMIT 50
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/entity/Q13693967'), ('obj', 'http://www.wikidata.org/entity/Q959790'), ('top', 'Cross'), ('films', 'crime film')]
# [('p', 'http://www.wikidata.org/entity/Q20724304'), ('obj', 'http://www.wikidata.org/entity/Q959790'), ('top', 'The Purge: Election Year'), ('films', 'crime film')]
# [('p', 'http://www.wikidata.org/entity/Q15865603'), ('obj', 'http://www.wikidata.org/entity/Q959790'), ('top', 'After Dark'), ('films', 'crime film')]
# [('p', 'http://www.wikidata.org/entity/Q1755064'), ('obj', 'http://www.wikidata.org/entity/Q959790'), ('top', "Sharky's Machine"), ('films', 'crime film')]
# [('p', 'http://www.wikidata.org/entity/Q11510316'), ('obj', 'http://www.wikidata.org/entity/Q959790'), ('top', 'Love Under Fire'), ('films', 'crime film')]
# [('p', 'http://www.wikidata.org/entity/Q16020981'), ('obj', 'http://www.wikidata.org/entity/Q959790'), ('top', 'The Amazing Partnership'), ('films', 'crime film')]
# [('p', 'http://www.wikidata.org/entity/Q16028315'), ('obj', 'http://www.wikidata.org/entity/Q959790'), ('top', 'The Bruce Partington Plans'), ('films', 'crime film')]
# [('p', 'http://www.wikidata.org/entity/Q16028374'), ('obj', 'http://www.wikidata.org/entity/Q959790'), ('top', 'The Dancing Men'), ('films', 'crime film')]
# [('p', 'http://www.wikidata.org/entity/Q16028732'), ('obj', 'http://www.wikidata.org/entity/Q959790'), ('top', 'The Naval Treaty'), ('films', 'crime film')]
# [('p', 'http://www.wikidata.org/entity/Q16200305'), ('obj', 'http://www.wikidata.org/entity/Q959790'), ('top', 'Fangs of the Arctic'), ('films', 'crime film')]
# [('p', 'http://www.wikidata.org/entity/Q16202837'), ('obj', 'http://www.wikidata.org/entity/Q959790'), ('top', 'China White'), ('films', 'crime film')]
# [('p', 'http://www.wikidata.org/entity/Q17492514'), ('obj', 'http://www.wikidata.org/entity/Q959790'), ('top', 'Talvar'), ('films', 'crime film')]
# [('p', 'http://www.wikidata.org/entity/Q9125658'), ('obj', 'http://www.wikidata.org/entity/Q959790'), ('top', 'Red Dragon'), ('films', 'crime film')]
# [('p', 'http://www.wikidata.org/entity/Q17036340'), ('obj', 'http://www.wikidata.org/entity/Q959790'), ('top', 'Mad Dog Coll'), ('films', 'crime film')]
# [('p', 'http://www.wikidata.org/entity/Q60016'), ('obj', 'http://www.wikidata.org/entity/Q959790'), ('top', 'Kiss the Girls'), ('films', 'crime film')]
# [('p', 'http://www.wikidata.org/entity/Q17168799'), ('obj', 'http://www.wikidata.org/entity/Q959790'), ('top', 'murdered'), ('films', 'crime film')]
# [('p', 'http://www.wikidata.org/entity/Q17212079'), ('obj', 'http://www.wikidata.org/entity/Q959790'), ('top', 'Mosquito on the Tenth Floor'), ('films', 'crime film')]
# [('p', 'http://www.wikidata.org/entity/Q17480384'), ('obj', 'http://www.wikidata.org/entity/Q959790'), ('top', 'Take'), ('films', 'crime film')]
# [('p', 'http://www.wikidata.org/entity/Q17511045'), ('obj', 'http://www.wikidata.org/entity/Q959790'), ('top', 'Alias French Gertie'), ('films', 'crime film')]
# [('p', 'http://www.wikidata.org/entity/Q46600556'), ('obj', 'http://www.wikidata.org/entity/Q959790'), ('top', 'Anti-Social'), ('films', 'crime film')]
# [('p', 'http://www.wikidata.org/entity/Q17625720'), ('obj', 'http://www.wikidata.org/entity/Q959790'), ('top', 'Adventures Inc.'), ('films', 'crime film')]
# [('p', 'http://www.wikidata.org/entity/Q17639912'), ('obj', 'http://www.wikidata.org/entity/Q959790'), ('top', 'The Lawless Woman'), ('films', 'crime film')]
# [('p', 'http://www.wikidata.org/entity/Q4183371'), ('obj', 'http://www.wikidata.org/entity/Q959790'), ('top', 'Peril at End House'), ('films', 'crime film')]
# [('p', 'http://www.wikidata.org/entity/Q1107774'), ('obj', 'http://www.wikidata.org/entity/Q959790'), ('top', 'No Place to Hide'), ('films', 'crime film')]
# [('p', 'http://www.wikidata.org/entity/Q18149041'), ('obj', 'http://www.wikidata.org/entity/Q959790'), ('top', 'Criminal'), ('films', 'crime film')]
# [('p', 'http://www.wikidata.org/entity/Q18149430'), ('obj', 'http://www.wikidata.org/entity/Q959790'), ('top', "Don't Turn 'Em Loose"), ('films', 'crime film')]
# [('p', 'http://www.wikidata.org/entity/Q18150133'), ('obj', 'http://www.wikidata.org/entity/Q959790'), ('top', 'Double Danger'), ('films', 'crime film')]
# [('p', 'http://www.wikidata.org/entity/Q18150397'), ('obj', 'http://www.wikidata.org/entity/Q959790'), ('top', 'Grand Jury'), ('films', 'crime film')]
# [('p', 'http://www.wikidata.org/entity/Q18153213'), ('obj', 'http://www.wikidata.org/entity/Q959790'), ('top', 'Post Office Investigator'), ('films', 'crime film')]
# [('p', 'http://www.wikidata.org/entity/Q1171611'), ('obj', 'http://www.wikidata.org/entity/Q959790'), ('top', 'Silent Rage'), ('films', 'crime film')]
# [('p', 'http://www.wikidata.org/entity/Q180125'), ('obj', 'http://www.wikidata.org/entity/Q959790'), ('top', 'Step Up'), ('films', 'crime film')]
# [('p', 'http://www.wikidata.org/entity/Q7246065'), ('obj', 'http://www.wikidata.org/entity/Q959790'), ('top', 'Private Detective 62'), ('films', 'crime film')]
# [('p', 'http://www.wikidata.org/entity/Q7779266'), ('obj', 'http://www.wikidata.org/entity/Q959790'), ('top', 'Top of the Lake'), ('films', 'crime film')]
# [('p', 'http://www.wikidata.org/entity/Q7993855'), ('obj', 'http://www.wikidata.org/entity/Q959790'), ('top', 'Whiskey Bay'), ('films', 'crime film')]
# [('p', 'http://www.wikidata.org/entity/Q20945857'), ('obj', 'http://www.wikidata.org/entity/Q959790'), ('top', 'Exit of Love Hotel'), ('films', 'crime film')]
# [('p', 'http://www.wikidata.org/entity/Q20949824'), ('obj', 'http://www.wikidata.org/entity/Q959790'), ('top', 'Before Morning'), ('films', 'crime film')]
# [('p', 'http://www.wikidata.org/entity/Q20949912'), ('obj', 'http://www.wikidata.org/entity/Q959790'), ('top', 'Missing Witnesses'), ('films', 'crime film')]
# [('p', 'http://www.wikidata.org/entity/Q21646989'), ('obj', 'http://www.wikidata.org/entity/Q959790'), ('top', 'Shantytown'), ('films', 'crime film')]
# [('p', 'http://www.wikidata.org/entity/Q21647049'), ('obj', 'http://www.wikidata.org/entity/Q959790'), ('top', 'Street of Fury'), ('films', 'crime film')]
# [('p', 'http://www.wikidata.org/entity/Q22972733'), ('obj', 'http://www.wikidata.org/entity/Q959790'), ('top', 'A Woman Going in Reverse'), ('films', 'crime film')]
# [('p', 'http://www.wikidata.org/entity/Q22975383'), ('obj', 'http://www.wikidata.org/entity/Q959790'), ('top', 'The Woman of Tuesday Night'), ('films', 'crime film')]
# [('p', 'http://www.wikidata.org/entity/Q24206207'), ('obj', 'http://www.wikidata.org/entity/Q959790'), ('top', 'The Five'), ('films', 'crime film')]
# [('p', 'http://www.wikidata.org/entity/Q26266013'), ('obj', 'http://www.wikidata.org/entity/Q959790'), ('top', 'Tatort: Die Kunst des Krieges'), ('films', 'crime film')]
# [('p', 'http://www.wikidata.org/entity/Q26832942'), ('obj', 'http://www.wikidata.org/entity/Q959790'), ('top', 'Rapl'), ('films', 'crime film')]
# [('p', 'http://www.wikidata.org/entity/Q27039081'), ('obj', 'http://www.wikidata.org/entity/Q959790'), ('top', 'Santoalla'), ('films', 'crime film')]
# [('p', 'http://www.wikidata.org/entity/Q27040209'), ('obj', 'http://www.wikidata.org/entity/Q959790'), ('top', 'Smooth Talker'), ('films', 'crime film')]
# [('p', 'http://www.wikidata.org/entity/Q263930'), ('obj', 'http://www.wikidata.org/entity/Q959790'), ('top', 'The Next Three Days'), ('films', 'crime film')]
# [('p', 'http://www.wikidata.org/entity/Q30668183'), ('obj', 'http://www.wikidata.org/entity/Q959790'), ('top', 'Big City Secret'), ('films', 'crime film')]
# [('p', 'http://www.wikidata.org/entity/Q4373735'), ('obj', 'http://www.wikidata.org/entity/Q959790'), ('top', 'Nobels testamente'), ('films', 'crime film')]
# [('p', 'http://www.wikidata.org/entity/Q35777951'), ('obj', 'http://www.wikidata.org/entity/Q959790'), ('top', 'Bond of Fear'), ('films', 'crime film')]
# 50

# %% [markdown]
# Final query for this task

# %%
#[('get', 'http://www.wikidata.org/prop/direct/P136'), ('getname', 'genre')]
#[('get', 'http://www.wikidata.org/entity/Q11424'), ('getname', 'film')]
queryString = """
SELECT DISTINCT ?p ?obj ?top ?films ?pcn ?abc
WHERE {
   # bind something
   # ?p wdt:P136 ?obj;
      wdt:P272 ?pcn.
   #get the label
   # ?p sc:name ?top.
   # ?obj sc:name ?films.
   # ?pcn sc:name ?abc
   FILTER(REGEX(?films,"crime film"^^xsd:string ))
   

}
LIMIT 80
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/entity/Q26266013'), ('obj', 'http://www.wikidata.org/entity/Q959790'), ('top', 'Tatort: Die Kunst des Krieges'), ('films', 'crime film'), ('pcn', 'http://www.wikidata.org/entity/Q2367528'), ('abc', 'Superfilm')]
# [('p', 'http://www.wikidata.org/entity/Q459057'), ('obj', 'http://www.wikidata.org/entity/Q959790'), ('top', 'Monster'), ('films', 'crime film'), ('pcn', 'http://www.wikidata.org/entity/Q5204823'), ('abc', 'DEJ Productions')]
# [('p', 'http://www.wikidata.org/entity/Q496113'), ('obj', 'http://www.wikidata.org/entity/Q959790'), ('top', 'City of Industry'), ('films', 'crime film'), ('pcn', 'http://www.wikidata.org/entity/Q17346576'), ('abc', 'Largo Entertainment')]
# [('p', 'http://www.wikidata.org/entity/Q498983'), ('obj', 'http://www.wikidata.org/entity/Q959790'), ('top', 'Young and Innocent'), ('films', 'crime film'), ('pcn', 'http://www.wikidata.org/entity/Q2756503'), ('abc', 'Gaumont-British Picture Corporation')]
# [('p', 'http://www.wikidata.org/entity/Q501105'), ('obj', 'http://www.wikidata.org/entity/Q959790'), ('top', 'The 39 Steps'), ('films', 'crime film'), ('pcn', 'http://www.wikidata.org/entity/Q2756503'), ('abc', 'Gaumont-British Picture Corporation')]
# [('p', 'http://www.wikidata.org/entity/Q680573'), ('obj', 'http://www.wikidata.org/entity/Q959790'), ('top', 'The Thousand Eyes of Dr. Mabuse'), ('films', 'crime film'), ('pcn', 'http://www.wikidata.org/entity/Q676498'), ('abc', 'CCC Film')]
# [('p', 'http://www.wikidata.org/entity/Q12131571'), ('obj', 'http://www.wikidata.org/entity/Q959790'), ('top', 'Villain'), ('films', 'crime film'), ('pcn', 'http://www.wikidata.org/entity/Q4353408'), ('abc', 'EMI Films')]
# [('p', 'http://www.wikidata.org/entity/Q1146552'), ('obj', 'http://www.wikidata.org/entity/Q959790'), ('top', 'Point Break'), ('films', 'crime film'), ('pcn', 'http://www.wikidata.org/entity/Q17346576'), ('abc', 'Largo Entertainment')]
# [('p', 'http://www.wikidata.org/entity/Q5376180'), ('obj', 'http://www.wikidata.org/entity/Q959790'), ('top', 'Endless Night'), ('films', 'crime film'), ('pcn', 'http://www.wikidata.org/entity/Q4353408'), ('abc', 'EMI Films')]
# [('p', 'http://www.wikidata.org/entity/Q19850804'), ('obj', 'http://www.wikidata.org/entity/Q959790'), ('top', 'Polizeiruf 110: Hexenjagd'), ('films', 'crime film'), ('pcn', 'http://www.wikidata.org/entity/Q19899'), ('abc', 'Rundfunk Berlin-Brandenburg')]
# [('p', 'http://www.wikidata.org/entity/Q1402883'), ('obj', 'http://www.wikidata.org/entity/Q959790'), ('top', 'Nancy Drew'), ('films', 'crime film'), ('pcn', 'http://www.wikidata.org/entity/Q17345505'), ('abc', 'Jerry Weintraub Productions')]
# [('p', 'http://www.wikidata.org/entity/Q1490812'), ('obj', 'http://www.wikidata.org/entity/Q959790'), ('top', 'Gacy'), ('films', 'crime film'), ('pcn', 'http://www.wikidata.org/entity/Q5204823'), ('abc', 'DEJ Productions')]
# [('p', 'http://www.wikidata.org/entity/Q1055796'), ('obj', 'http://www.wikidata.org/entity/Q959790'), ('top', 'The Long Good Friday'), ('films', 'crime film'), ('pcn', 'http://www.wikidata.org/entity/Q3149951'), ('abc', 'ITC Entertainment')]
# [('p', 'http://www.wikidata.org/entity/Q733677'), ('obj', 'http://www.wikidata.org/entity/Q959790'), ('top', 'Match Point'), ('films', 'crime film'), ('pcn', 'http://www.wikidata.org/entity/Q7752106'), ('abc', 'The Montecito Picture Company')]
# [('p', 'http://www.wikidata.org/entity/Q3441176'), ('obj', 'http://www.wikidata.org/entity/Q959790'), ('top', 'Rome Express'), ('films', 'crime film'), ('pcn', 'http://www.wikidata.org/entity/Q2756503'), ('abc', 'Gaumont-British Picture Corporation')]
# [('p', 'http://www.wikidata.org/entity/Q2370768'), ('obj', 'http://www.wikidata.org/entity/Q959790'), ('top', 'The Meeting Place Cannot Be Changed'), ('films', 'crime film'), ('pcn', 'http://www.wikidata.org/entity/Q2628487'), ('abc', 'Odessa Film Studio')]
# [('p', 'http://www.wikidata.org/entity/Q5302848'), ('obj', 'http://www.wikidata.org/entity/Q959790'), ('top', 'Down River'), ('films', 'crime film'), ('pcn', 'http://www.wikidata.org/entity/Q2756503'), ('abc', 'Gaumont-British Picture Corporation')]
# [('p', 'http://www.wikidata.org/entity/Q1171580'), ('obj', 'http://www.wikidata.org/entity/Q959790'), ('top', 'The Seventh Victim'), ('films', 'crime film'), ('pcn', 'http://www.wikidata.org/entity/Q676498'), ('abc', 'CCC Film')]
# [('p', 'http://www.wikidata.org/entity/Q2900179'), ('obj', 'http://www.wikidata.org/entity/Q959790'), ('top', 'Better Luck Tomorrow'), ('films', 'crime film'), ('pcn', 'http://www.wikidata.org/entity/Q1111024'), ('abc', 'MTV Films')]
# [('p', 'http://www.wikidata.org/entity/Q7738215'), ('obj', 'http://www.wikidata.org/entity/Q959790'), ('top', 'The Green Terror'), ('films', 'crime film'), ('pcn', 'http://www.wikidata.org/entity/Q2756503'), ('abc', 'Gaumont-British Picture Corporation')]
# [('p', 'http://www.wikidata.org/entity/Q590252'), ('obj', 'http://www.wikidata.org/entity/Q959790'), ('top', 'Jack Reacher'), ('films', 'crime film'), ('pcn', 'http://www.wikidata.org/entity/Q3005562'), ('abc', 'Cruise/Wagner Productions')]
# [('p', 'http://www.wikidata.org/entity/Q42759035'), ('obj', 'http://www.wikidata.org/entity/Q959790'), ('top', 'Joker'), ('films', 'crime film'), ('pcn', 'http://www.wikidata.org/entity/Q3011161'), ('abc', 'DC Entertainment')]
# [('p', 'http://www.wikidata.org/entity/Q980257'), ('obj', 'http://www.wikidata.org/entity/Q959790'), ('top', 'Evil Under the Sun'), ('films', 'crime film'), ('pcn', 'http://www.wikidata.org/entity/
), ('films', 'crime film'), ('pcn', 'http://www.wikidata.org/entity/Q107391544'), ('abc', 'Curtleigh Productions')]
# [('p', 'http://www.wikidata.org/entity/Q1059914'), ('obj', 'http://www.wikidata.org/entity/Q959790'), ('top', 'Death on the Nile'), ('films', 'crime film'), ('pcn', 'http://www.wikidata.org/entity/Q4353408'), ('abc', 'EMI Films')]
# [('p', 'http://www.wikidata.org/entity/Q3521099'), ('obj', 'http://www.wikidata.org/entity/Q959790'), ('top', 'The Grand Budapest Hotel'), ('films', 'crime film'), ('pcn', 'http://www.wikidata.org/entity/Q18155354'), ('abc', 'TSG Entertainment')]
# [('p', 'http://www.wikidata.org/entity/Q464111'), ('obj', 'http://www.wikidata.org/entity/Q959790'), ('top', 'The Boys from Brazil'), ('films', 'crime film'), ('pcn', 'http://www.wikidata.org/entity/Q3149951'), ('abc', 'ITC Entertainment')]
# [('p', 'http://www.wikidata.org/entity/Q4762134'), ('obj', 'http://www.wikidata.org/entity/Q959790'), ('top', 'Angel Esquire'), ('films', 'crime film'), ('pcn', 'http://www.wikidata.org/entity/Q2756503'), ('abc', 'Gaumont-British Picture Corporation')]
# [('p', 'http://www.wikidata.org/entity/Q500044'), ('obj', 'http://www.wikidata.org/entity/Q959790'), ('top', 'The Lady Vanishes'), ('films', 'crime film'), ('pcn', 'http://www.wikidata.org/entity/Q2756503'), ('abc', 'Gaumont-British Picture Corporation')]
# [('p', 'http://www.wikidata.org/entity/Q1192773'), ('obj', 'http://www.wikidata.org/entity/Q959790'), ('top', 'Confessions of a Police Captain'), ('films', 'crime film'), ('pcn', 'http://www.wikidata.org/entity/Q3734691'), ('abc', 'Euro International Film')]
# [('p', 'http://www.wikidata.org/entity/Q4660755'), ('obj', 'http://www.wikidata.org/entity/Q959790'), ('top', 'A Woman in Pawn'), ('films', 'crime film'), ('pcn', 'http://www.wikidata.org/entity/Q2756503'), ('abc', 'Gaumont-British Picture Corporation')]
# [('p', 'http://www.wikidata.org/entity/Q19871451'), ('obj', 'http://www.wikidata.org/entity/Q959790'), ('top', 'Bracelets'), ('films', 'crime film'), ('pcn', 'http://www.wikidata.org/entity/Q2756503'), ('abc', 'Gaumont-British Picture Corporation')]
# [('p', 'http://www.wikidata.org/entity/Q30321613'), ('obj', 'http://www.wikidata.org/entity/Q959790'), ('top', 'Hotel Artemis'), ('films', 'crime film'), ('pcn', 'http://www.wikidata.org/entity/Q17417784'), ('abc', 'Marc Platt Productions')]
# [('p', 'http://www.wikidata.org/entity/Q7754148'), ('obj', 'http://www.wikidata.org/entity/Q959790'), ('top', 'The Night of the Party'), ('films', 'crime film'), ('pcn', 'http://www.wikidata.org/entity/Q2756503'), ('abc', 'Gaumont-British Picture Corporation')]
# [('p', 'http://www.wikidata.org/entity/Q7766112'), ('obj', 'http://www.wikidata.org/entity/Q959790'), ('top', 'The Squeaker'), ('films', 'crime film'), ('pcn', 'http://www.wikidata.org/entity/Q1868978'), ('abc', 'London Films')]
# [('p', 'http://www.wikidata.org/entity/Q2543979'), ('obj', 'http://www.wikidata.org/entity/Q959790'), ('top', "The Mirror Crack'd"), ('films', 'crime film'), ('pcn', 'http://www.wikidata.org/entity/Q4353408'), ('abc', 'EMI Films')]
# [('p', 'http://www.wikidata.org/entity/Q18209189'), ('obj', 'http://www.wikidata.org/entity/Q959790'), ('top', 'Man in the River'), ('films', 'crime film'), ('pcn', 'http://www.wikidata.org/entity/Q676498'), ('abc', 'CCC Film')]
# [('p', 'http://www.wikidata.org/entity/Q71960'), ('obj', 'http://www.wikidata.org/entity/Q959790'), ('top', 'Save the Last Dance'), ('films', 'crime film'), ('pcn', 'http://www.wikidata.org/entity/Q1111024'), ('abc', 'MTV Films')]
# [('p', 'http://www.wikidata.org/entity/Q60661850'), ('obj', 'http://www.wikidata.org/entity/Q959790'), ('top', 'M – A City Hunts a Murderer'), ('films', 'crime film'), ('pcn', 'http://www.wikidata.org/entity/Q2367528'), ('abc', 'Superfilm')]
# [('p', 'http://www.wikidata.org/entity/Q1216781'), ('obj', 'http://www.wikidata.org/entity/Q959790'), ('top', 'The Secret of Dr. Mabuse'), ('films', 'crime film'), ('pcn', 'http://www.wikidata.org/entity/Q676498'), ('abc', 'CCC Film')]
# [('p', 'http://www.wikidata.org/entity/Q1678247'), ('obj', 'http://www.wikidata.org/entity/Q959790'), ('top', 'The Firechasers'), ('films', 'crime film'), ('pcn', 'http://www.wikidata.org/entity/Q3149951'), ('abc', 'ITC Entertainment')]
# [('p', 'http://www.wikidata.org/entity/Q761688'), ('obj', 'http://www.wikidata.org/entity/Q959790'), ('top', 'Love and Bullets'), ('films', 'crime film'), ('pcn', 'http://www.wikidata.org/entity/Q3149951'), ('abc', 'ITC Entertainment')]
# [('p', 'http://www.wikidata.org/entity/Q4241042'), ('obj', 'http://www.wikidata.org/entity/Q959790'), ('top', 'Criminal Talent'), ('films', 'crime film'), ('pcn', 'http://www.wikidata.org/entity/Q2628487'), ('abc', 'Odessa Film Studio')]
# [('p', 'http://www.wikidata.org/entity/Q7127738'), ('obj', 'http://www.wikidata.org/entity/Q959790'), ('top', 'Pallard the Punter'), ('films', 'crime film'), ('pcn', 'http://www.wikidata.org/entity/Q2756503'), ('abc', 'Gaumont-British Picture Corporation')]
# [('p', 'http://www.wikidata.org/entity/Q14949835'), ('obj', 'http://www.wikidata.org/entity/Q959790'), ('top', 'Non-Stop New York'), ('films', 'crime film'), ('pcn', 'http://www.wikidata.org/entity/Q2756503'), ('abc', 'Gaumont-British Picture Corporation')]
# [('p', 'http://www.wikidata.org/entity/Q1193825'), ('obj', 'http://www.wikidata.org/entity/Q959790'), ('top', 'Affliction'), ('films', 'crime film'), ('pcn', 'http://www.wikidata.org/entity/Q17346576'), ('abc', 'Largo Entertainment')]
# [('p', 'http://www.wikidata.org/entity/Q2753655'), ('obj', 'http://www.wikidata.org/entity/Q959790'), ('top', 'Silver Bears'), ('films', 'crime film'), ('pcn', 'http://www.wikidata.org/entity/Q4353408'), ('abc', 'EMI Films')]
# [('p', 'http://www.wikidata.org/entity/Q28952116'), ('obj', 'http://www.wikidata.org/entity/Q959790'), ('top', 'Angamaly Diaries'), ('films', 'crime film'), ('pcn', 'http://www.wikidata.org/entity/Q22080360'), ('abc', 'Friday Film House')]
# [('p', 'http://www.wikidata.org/entity/Q4373735'), ('obj', 'http://www.wikidata.org/entity/Q959790'), ('top', 'Nobels testamente'), ('films', 'crime film'), ('pcn', 'http://www.wikidata.org/entity/Q8051674'), ('abc', 'Yellow Bird')]
# [('p', 'http://www.wikidata.org/entity/Q604912'), ('obj', 'http://www.wikidata.org/entity/Q959790'), ('top', 'Cop or Hood'), ('films', 'crime film'), ('pcn', 'http://www.wikidata.org/entity/Q18331625'), ('abc', 'Cerito Films')]
# [('p', 'http://www.wikidata.org/entity/Q654474'), ('obj', 'http://www.wikidata.org/entity/Q959790'), ('top', 'T-Men'), ('films', 'crime film'), ('pcn', 'http://www.wikidata.org/entity/Q17377479'), ('abc', 'Edward Small Productions')]
# 80

# %% [markdown]
# ## Task 6
# Find the company (amongst television production company and film production company) which distributed more films (of any kind of film genre) that they did not produce (the result set must be a list of triples company IRI, label and #film).

# %%
#TOTAL FILMS BY EACH COMPANY
#[('get', 'http://www.wikidata.org/prop/direct/P136'), ('getname', 'genre')]
#[('get', 'http://www.wikidata.org/entity/Q11424'), ('getname', 'film')]
queryString = """
SELECT DISTINCT (COUNT(?p) AS ?tf) ?pcn ?abc
WHERE {
   # bind something
   # ?p wdt:P136 ?obj;
      wdt:P272 ?pcn.
   #get the label
   # ?p sc:name ?top.
   # ?obj sc:name ?films.
   # ?pcn sc:name ?abc
   FILTER(REGEX(?films,"crime film"^^xsd:string ))
   

}
GROUP BY ?abc ?pcn
LIMIT 80
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('tf', '2'), ('pcn', 'http://www.wikidata.org/entity/
]
# [('tf', '2'), ('pcn', 'http://www.wikidata.org/entity/Q2714773'), ('abc', 'Caravan Pictures')]
# [('tf', '1'), ('pcn', 'http://www.wikidata.org/entity/Q1414782'), ('abc', 'Filmistan')]
# [('tf', '1'), ('pcn', 'http://www.wikidata.org/entity/Q4050610'), ('abc', 'TOR film studio')]
# [('tf', '1'), ('pcn', 'http://www.wikidata.org/entity/Q1022286'), ('abc', 'C-Films')]
# [('tf', '1'), ('pcn', 'http://www.wikidata.org/entity/Q49851272'), ('abc', 'Cinévidéo')]
# [('tf', '1'), ('pcn', 'http://www.wikidata.org/entity/Q5285236'), ('abc', 'Django Films')]
# [('tf', '6'), ('pcn', 'http://www.wikidata.org/entity/Q3406645'), ('abc', 'Producers Releasing Corporation')]
# [('tf', '1'), ('pcn', 'http://www.wikidata.org/entity/Q719998'), ('abc', 'Tallinnfilm')]
# [('tf', '1'), ('pcn', 'http://www.wikidata.org/entity/Q1916145'), ('abc', 'MediaNews Group')]
# [('tf', '2'), ('pcn', 'http://www.wikidata.org/entity/Q527751'), ('abc', 'Mascot Pictures')]
# [('tf', '2'), ('pcn', 'http://www.wikidata.org/entity/Q7924435'), ('abc', 'Viacom 18 Motion Pictures')]
# [('tf', '2'), ('pcn', 'http://www.wikidata.org/entity/Q5389773'), ('abc', 'Erler Film')]
# [('tf', '1'), ('pcn', 'http://www.wikidata.org/entity/Q1523434'), ('abc', 'Maurice Tourneur')]
# [('tf', '1'), ('pcn', 'http://www.wikidata.org/entity/Q28071268'), ('abc', 'Canana Films')]
# [('tf', '1'), ('pcn', 'http://www.wikidata.org/entity/Q7883673'), ('abc', 'Underground contenidos')]
# [('tf', '2'), ('pcn', 'http://www.wikidata.org/entity/Q57832058'), ('abc', 'Bidibul Productions')]
# [('tf', '1'), ('pcn', 'http://www.wikidata.org/entity/Q17067950'), ('abc', 'Jaaz Multimedia')]
# [('tf', '1'), ('pcn', 'http://www.wikidata.org/entity/Q64667698'), ('abc', 'Zodiac Pictures')]
# [('tf', '1'), ('pcn', 'http://www.wikidata.org/entity/Q3429960'), ('abc', 'Auvergne-Rhône-Alpes Cinéma')]
# [('tf', '3'), ('pcn', 'http://www.wikidata.org/entity/Q5448895'), ('abc', 'FilmNation Entertainment')]
# [('tf', '1'), ('pcn', 'http://www.wikidata.org/entity/Q3294957'), ('abc', 'Mars Films')]
# [('tf', '1'), ('pcn', 'http://www.wikidata.org/entity/Q2861044'), ('abc', 'Argos Films')]
# [('tf', '1'), ('pcn', 'http://www.wikidata.org/entity/Q3875639'), ('abc', 'Newmarket Films')]
# [('tf', '1'), ('pcn', 'http://www.wikidata.org/entity/Q6952279'), ('abc', 'NALA Films')]
# [('tf', '1'), ('pcn', 'http://www.wikidata.org/entity/Q85795495'), ('abc', 'RSVP Movies')]
# [('tf', '1'), ('pcn', 'http://www.wikidata.org/entity/Q17385899'), ('abc', 'Solar Productions')]
# [('tf', '2'), ('pcn', 'http://www.wikidata.org/entity/Q3232649'), ('abc', 'Les Films du Carrosse')]
# [('tf', '1'), ('pcn', 'http://www.wikidata.org/entity/Q10590609'), ('abc', 'Mushroom Pictures')]
# [('tf', '1'), ('pcn', 'http://www.wikidata.org/entity/Q2155901'), ('abc', 'Road Movies Filmproduktion')]
# [('tf', '1'), ('pcn', 'http://www.wikidata.org/entity/Q24190766'), ('abc', 'No Trace Camping')]
# [('tf', '2'), ('pcn', 'http://www.wikidata.org/entity/Q55237528'), ('abc', 'STXfilms')]
# [('tf', '1'), ('pcn', 'http://www.wikidata.org/entity/Q7983208'), ('abc', 'Werc Werk Works')]
# 80

# %% [markdown]
# Final query for this task

# %%
# TOP 10 FILM PRODUCTION COMPANIES
#[('get', 'http://www.wikidata.org/prop/direct/P136'), ('getname', 'genre')]
#[('get', 'http://www.wikidata.org/entity/Q11424'), ('getname', 'film')]
queryString = """
SELECT DISTINCT (COUNT(?p) AS ?tf) ?pcn ?abc
WHERE {
   # bind something
   # ?p wdt:P136 ?obj;
      wdt:P272 ?pcn.
   #get the label
   # ?p sc:name ?top.
   # ?obj sc:name ?films.
   # ?pcn sc:name ?abc
   FILTER(REGEX(?films,"crime film"^^xsd:string ))
   

}
GROUP BY ?abc ?pcn
ORDER BY DESC(?tf)
LIMIT 10
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('tf', '161'), ('pcn', 'http://www.wikidata.org/entity/Q126399'), ('abc', 'Warner Bros.')]
# [('tf', '118'), ('pcn', 'http://www.wikidata.org/entity/Q186941'), ('abc', 'Columbia Pictures')]
# [('tf', '113'), ('pcn', 'http://www.wikidata.org/entity/Q168383'), ('abc', 'Universal Pictures')]
# [('tf', '112'), ('pcn', 'http://www.wikidata.org/entity/Q179200'), ('abc', 'Metro-Goldwyn-Mayer')]
# [('tf', '109'), ('pcn', 'http://www.wikidata.org/entity/Q159846'), ('abc', 'Paramount Pictures')]
# [('tf', '90'), ('pcn', 'http://www.wikidata.org/entity/Q434841'), ('abc', '20th Century Studios')]
# [('tf', '87'), ('pcn', 'http://www.wikidata.org/entity/Q267282'), ('abc', 'RKO Pictures')]
# [('tf', '37'), ('pcn', 'http://www.wikidata.org/entity/Q913462'), ('abc', 'Gaumont Film Company')]
# [('tf', '35'), ('pcn', 'http://www.wikidata.org/entity/Q2450848'), ('abc', 'StudioCanal')]
# [('tf', '34'), ('pcn', 'http://www.wikidata.org/entity/Q79202'), ('abc', 'New Line Cinema')]
# 10

# %% [markdown]
# ## Task 7
# Find how many company are listed in every stock exchange market (the result set must be a list of triples stock exchange IRI, label and #companies).

# %%
# WE USE SUB CLASS OF PRODUCTION COMPANY FROM TASK 3 RESULT TO CHECK COMPANIES LISTED IN STOCK EXCHANGE
#[('p', 'http://www.wikidata.org/prop/direct/P279'), ('as', 'subclass of'), ('i', 'http://www.wikidata.org/entity/Q11396960'), ('op', 'production company')]
queryString = """
SELECT DISTINCT ?p ?as ?op ?i
WHERE {
   # bind something
   wd:Q11396960 ?p ?i.
   #get the label
   # ?p sc:name ?as.
   # ?i sc:name ?op
   
   

}
LIMIT 10
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P101'), ('as', 'field of work'), ('op', 'audiovisual production'), ('i', 'http://www.wikidata.org/entity/Q21198548')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('as', 'subclass of'), ('op', 'media company'), ('i', 'http://www.wikidata.org/entity/Q1331793')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('as', 'subclass of'), ('op', 'company'), ('i', 'http://www.wikidata.org/entity/Q783794')]
# [('p', 'http://www.wikidata.org/prop/direct/P1687'), ('as', 'Wikidata property'), ('op', 'production company'), ('i', 'http://www.wikidata.org/entity/P272')]
# 4

# %% [markdown]
# Final query for this task

# %%
# WE WILL FURTHER ELABORATE MEDIA COMPANY TO CHECK COMPANIES INVOLVED IN STOCK EXCHANGE
#[('p', 'http://www.wikidata.org/prop/direct/P279'), ('as', 'subclass of'), ('op', 'media company'), ('i', 'http://www.wikidata.org/entity/Q1331793')]
queryString = """
SELECT DISTINCT ?p ?as ?op ?i
WHERE {
   # bind something
   wd:Q1331793 ?p ?i.
   #get the label
   # ?p sc:name ?as.
   # ?i sc:name ?op
   
   

}
LIMIT 10
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P1889'), ('as', 'different from'), ('op', 'media studio facility'), ('i', 'http://www.wikidata.org/entity/Q19364326')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('as', 'subclass of'), ('op', 'business'), ('i', 'http://www.wikidata.org/entity/Q4830453')]
# [('p', 'http://www.wikidata.org/prop/direct/P2283'), ('as', 'uses'), ('op', 'communication'), ('i', 'http://www.wikidata.org/entity/Q11024')]
# [('p', 'http://www.wikidata.org/prop/direct/P101'), ('as', 'field of work'), ('op', 'mass media'), ('i', 'http://www.wikidata.org/entity/Q11033')]
# [('p', 'http://www.wikidata.org/prop/direct/P101'), ('as', 'field of work'), ('op', 'communication medium'), ('i', 'http://www.wikidata.org/entity/Q340169')]
# [('p', 'http://www.wikidata.org/prop/direct/P2283'), ('as', 'uses'), ('op', 'communication medium'), ('i', 'http://www.wikidata.org/entity/Q340169')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('as', 'subclass of'), ('op', 'company'), ('i', 'http://www.wikidata.org/entity/Q783794')]
# [('p', 'http://www.wikidata.org/prop/direct/P910'), ('as', "topic's main category"), ('op', 'Category:Mass media companies'), ('i', 'http://www.wikidata.org/entity/Q7110212')]
# 8

# %%
#NOW WE SELECT BUSSINESS FROM RESULTS AND FURTHER EXPLORE.
#[('p', 'http://www.wikidata.org/prop/direct/P279'), ('as', 'subclass of'), ('op', 'business'), ('i', 'http://www.wikidata.org/entity/Q4830453')]
queryString = """
SELECT DISTINCT ?p ?as ?op ?i
WHERE {
   # bind something
   wd:Q4830453 ?p ?i.
   #get the label
   # ?p sc:name ?as.
   # ?i sc:name ?op
   
   

}
LIMIT 10
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('as', 'properties for this type'), ('op', 'stock exchange'), ('i', 'http://www.wikidata.org/entity/P414')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('as', 'properties for this type'), ('op', 'Twitter username'), ('i', 'http://www.wikidata.org/entity/P2002')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('as', 'properties for this type'), ('op', 'Legal Entity Identifier'), ('i', 'http://www.wikidata.org/entity/P1278')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('as', 'properties for this type'), ('op', 'OpenCorporates ID'), ('i', 'http://www.wikidata.org/entity/P1320')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('as', 'properties for this type'), ('op', 'product or material produced'), ('i', 'http://www.wikidata.org/entity/P1056')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('as', 'properties for this type'), ('op', 'phone number'), ('i', 'http://www.wikidata.org/entity/P1329')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('as', 'properties for this type'), ('op', 'headquarters location'), ('i', 'http://www.wikidata.org/entity/P159')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('as', 'properties for this type'), ('op', 'dissolved, abolished or demolished date'), ('i', 'http://www.wikidata.org/entity/P576')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('as', 'properties for this type'), ('op', 'country'), ('i', 'http://www.wikidata.org/entity/P17')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('as', 'subclass of'), ('op', 'organization'), ('i', 'http://www.wikidata.org/entity/Q43229')]
# 10

# %%
# HERE IT IS WE GOT STOCK EXCHANGE IN FIRST ROW IN PREVIOUS RESULT NOW WE FURTHER EXPLORE STOCK EXCHANGE.
#[('p', 'http://www.wikidata.org/prop/direct/P1963'), ('as', 'properties for this type'), ('op', 'stock exchange'), ('i', 'http://www.wikidata.org/entity/P414')]
queryString = """
SELECT DISTINCT ?p ?as ?op ?i
WHERE {
   # bind something
   # ?P wdt:P414 ?i.
   #get the label
   # ?p sc:name ?as.
   # ?i sc:name ?op
   
   

}
LIMIT 10
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/entity/P348'), ('as', 'software version identifier'), ('op', 'Philippine Stock Exchange'), ('i', 'http://www.wikidata.org/entity/Q1526647')]
# [('p', 'http://www.wikidata.org/entity/P4669'), ('as', 'tabular software version'), ('op', 'Philippine Stock Exchange'), ('i', 'http://www.wikidata.org/entity/Q1526647')]
# [('p', 'http://www.wikidata.org/entity/P747'), ('as', 'has edition or translation'), ('op', 'Philippine Stock Exchange'), ('i', 'http://www.wikidata.org/entity/Q1526647')]
# [('p', 'http://www.wikidata.org/entity/Q1002728'), ('as', 'Fonsi Nieto'), ('op', 'Philippine Stock Exchange'), ('i', 'http://www.wikidata.org/entity/Q1526647')]
# [('p', 'http://www.wikidata.org/entity/Q100326534'), ('as', "Al Stewart's albums in chronological order"), ('op', 'Philippine Stock Exchange'), ('i', 'http://www.wikidata.org/entity/Q1526647')]
# [('p', 'http://www.wikidata.org/entity/Q100327667'), ('as', 'Category:Adelina Lopes Vieira'), ('op', 'Philippine Stock Exchange'), ('i', 'http://www.wikidata.org/entity/Q1526647')]
# [('p', 'http://www.wikidata.org/entity/Q100343342'), ('as', 'Lubomír Stoklásek'), ('op', 'Philippine Stock Exchange'), ('i', 'http://www.wikidata.org/entity/Q1526647')]
# [('p', 'http://www.wikidata.org/entity/Q1007576'), ('as', 'Ciudad Vieja'), ('op', 'Philippine Stock Exchange'), ('i', 'http://www.wikidata.org/entity/Q1526647')]
# [('p', 'http://www.wikidata.org/entity/Q100879156'), ('as', 'Echániz'), ('op', 'Philippine Stock Exchange'), ('i', 'http://www.wikidata.org/entity/Q1526647')]
# [('p', 'http://www.wikidata.org/entity/Q10100'), ('as', 'Natuna'), ('op', 'Philippine Stock Exchange'), ('i', 'http://www.wikidata.org/entity/Q1526647')]
# 10

# %%
# TOTAL NUMBEROF COMPANIES IN STOCK EXCHANGE
# TOTAL 200 COUNTRIES IN WORLD RIGHTNOW WE SET LIMIT FOR 200 TO SEE NUMBER OF COMPANIES IN EACH COUNTRY STOCK EXCHAGE. 
queryString = """
SELECT DISTINCT (COUNT(?P) as ?tnc)?old ?i
WHERE {
   # bind something
   # ?P wdt:P414 ?i.
   #get the label
   # ?i sc:name ?old
   
   

}
GROUP BY ?old ?i
LIMIT 200
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('tnc', '40'), ('old', 'SIX Swiss Exchange'), ('i', 'http://www.wikidata.org/entity/Q661834')]
# [('tnc', '6'), ('old', 'Xetra'), ('i', 'http://www.wikidata.org/entity/Q819468')]
# [('tnc', '460'), ('old', 'Tokyo Stock Exchange'), ('i', 'http://www.wikidata.org/entity/Q217475')]
# [('tnc', '1'), ('old', 'Bilbao Stock Exchange'), ('i', 'http://www.wikidata.org/entity/Q4890307')]
# [('tnc', '11'), ('old', 'PFTS Ukraine Stock Exchange'), ('i', 'http://www.wikidata.org/entity/Q1984912')]
# [('tnc', '346'), ('old', 'Nepal Stock Exchange'), ('i', 'http://www.wikidata.org/entity/Q6529599')]
# [('tnc', '58'), ('old', 'Nasdaq Helsinki'), ('i', 'http://www.wikidata.org/entity/Q581755')]
# [('tnc', '3'), ('old', 'Bulgarian Stock Exchange'), ('i', 'http://www.wikidata.org/entity/Q1003968')]
# [('tnc', '1'), ('old', 'CEX.io'), ('i', 'http://www.wikidata.org/entity/Q22907145')]
# [('tnc', '2'), ('old', 'Euronext Growth'), ('i', 'http://www.wikidata.org/entity/Q2718247')]
# [('tnc', '1'), ('old', 'Old Stock Exchange'), ('i', 'http://www.wikidata.org/entity/
# 177

# %% [markdown]
# ## Task 8
# Identify the BGP for Academy Award

# %%
queryString = """
SELECT DISTINCT ?P ?top ?films ?obj
WHERE {{
   # bind something
   wd:Q11424 ?P ?obj.
   #get the label
   # ?p sc:name ?top.
   # ?obj sc:name ?films.
   }
   Union
   {
   # ?P ?obj wd:Q11424.
   # ?p sc:name ?top.
   # ?obj sc:name ?films.
   }
   }
LIMIT 50
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('P', 'http://www.wikidata.org/prop/direct/P2579'), ('top', 'software version identifier'), ('films', 'film studies'), ('obj', 'http://www.wikidata.org/entity/Q1660187')]
# [('P', 'http://www.wikidata.org/prop/direct/P2579'), ('top', 'tabular software version'), ('films', 'film studies'), ('obj', 'http://www.wikidata.org/entity/Q1660187')]
# [('P', 'http://www.wikidata.org/prop/direct/P2579'), ('top', 'has edition or translation'), ('films', 'film studies'), ('obj', 'http://www.wikidata.org/entity/Q1660187')]
# [('P', 'http://www.wikidata.org/prop/direct/P2579'), ('top', 'Fonsi Nieto'), ('films', 'film studies'), ('obj', 'http://www.wikidata.org/entity/Q1660187')]
# [('P', 'http://www.wikidata.org/prop/direct/P2579'), ('top', "Al Stewart's albums in chronological order"), ('films', 'film studies'), ('obj', 'http://www.wikidata.org/entity/Q1660187')]
# [('P', 'http://www.wikidata.org/prop/direct/P2579'), ('top', 'Category:Adelina Lopes Vieira'), ('films', 'film studies'), ('obj', 'http://www.wikidata.org/entity/Q1660187')]
# [('P', 'http://www.wikidata.org/prop/direct/P2579'), ('top', 'Lubomír Stoklásek'), ('films', 'film studies'), ('obj', 'http://www.wikidata.org/entity/Q1660187')]
# [('P', 'http://www.wikidata.org/prop/direct/P2579'), ('top', 'Ciudad Vieja'), ('films', 'film studies'), ('obj', 'http://www.wikidata.org/entity/Q1660187')]
# [('P', 'http://www.wikidata.org/prop/direct/P2579'), ('top', 'Echániz'), ('films', 'film studies'), ('obj', 'http://www.wikidata.org/entity/Q1660187')]
# [('P', 'http://www.wikidata.org/prop/direct/P2579'), ('top', 'Natuna'), ('films', 'film studies'), ('obj', 'http://www.wikidata.org/entity/Q1660187')]
# [('P', 'http://www.wikidata.org/prop/direct/P2579'), ('top', "Acid Mothers Temple's albums in chronological order"), ('films', 'film studies'), ('obj', 'http://www.wikidata.org/entity/Q1660187')]
# [('P', 'http://www.wikidata.org/prop/direct/P2579'), ('top', 'Relaño'), ('films', 'film studies'), ('obj', 'http://www.wikidata.org/entity/Q1660187')]
# [('P', 'http://www.wikidata.org/prop/direct/P2579'), ('top', '2002 in transport'), ('films', 'film studies'), ('obj', 'http://www.wikidata.org/entity/Q1660187')]
# [('P', 'http://www.wikidata.org/prop/direct/P2579'), ('top', '2006 in transport'), ('films', 'film studies'), ('obj', 'http://www.wikidata.org/entity/Q1660187')]
# [('P', 'http://www.wikidata.org/prop/direct/P2579'), ('top', 'Category:1920 elections in Oceania'), ('films', 'film studies'), ('obj', 'http://www.wikidata.org/entity/Q1660187')]
# [('P', 'http://www.wikidata.org/prop/direct/P2579'), ('top', 'Category:2002 elections in South America'), ('films', 'film studies'), ('obj', 'http://www.wikidata.org/entity/Q1660187')]
# [('P', 'http://www.wikidata.org/prop/direct/P2579'), ('top', 'Category:Teluk Sebong'), ('films', 'film studies'), ('obj', 'http://www.wikidata.org/entity/Q1660187')]
# [('P', 'http://www.wikidata.org/prop/direct/P2579'), ('top', 'Võnnu Rural Municipality'), ('films', 'film studies'), ('obj', 'http://www.wikidata.org/entity/Q1660187')]
# [('P', 'http://www.wikidata.org/prop/direct/P2579'), ('top', 'Kojiro Kobayashi'), ('films', 'film studies'), ('obj', 'http://www.wikidata.org/entity/Q1660187')]
# [('P', 'http://www.wikidata.org/prop/direct/P2579'), ('top', 'Miguel E. M. Herrera'), ('films', 'film studies'), ('obj', 'http://www.wikidata.org/entity/Q1660187')]
# [('P', 'http://www.wikidata.org/prop/direct/P2579'), ('top', 'Category:Akita Shoten magazines'), ('films', 'film studies'), ('obj', 'http://www.wikidata.org/entity/Q1660187')]
# [('P', 'http://www.wikidata.org/prop/direct/P2579'), ('top', "2010 CONCACAF Women's Gold Cup"), ('films', 'film studies'), ('obj', 'http://www.wikidata.org/entity/Q1660187')]
# [('P', 'http://www.wikidata.org/prop/direct/P2579'), ('top', '2014 FIFA World Cup venues'), ('films', 'film studies'), ('obj', 'http://www.wikidata.org/entity/Q1660187')]
# [('P', 'http://www.wikidata.org/prop/direct/P2579'), ('top', 'ambassador of Guatemala to France'), ('films', 'film studies'), ('obj', 'http://www.wikidata.org/entity/Q1660187')]
# [('P', 'http://www.wikidata.org/prop/direct/P2579'), ('top', 'Estação Ferroviária de Mafra'), ('films', 'film studies'), ('obj', 'http://www.wikidata.org/entity/Q1660187')]
# [('P', 'http://www.wikidata.org/prop/direct/P2579'), ('top', 'Faculdade de Letras da Universidade de Coimbra'), ('films', 'film studies'), ('obj', 'http://www.wikidata.org/entity/Q1660187')]
# [('P', 'http://www.wikidata.org/prop/direct/P2579'), ('top', 'Faculty of Arts and Humanities of the University of Porto'), ('films', 'film studies'), ('obj', 'http://www.wikidata.org/entity/Q1660187')]
# [('P', 'http://www.wikidata.org/prop/direct/P2579'), ('top', 'Aji'), ('films', 'film studies'), ('obj', 'http://www.wikidata.org/entity/Q1660187')]
# [('P', 'http://www.wikidata.org/prop/direct/P2579'), ('top', 'Urucu'), ('films', 'film studies'), ('obj', 'http://www.wikidata.org/entity/Q1660187')]
# [('P', 'http://www.wikidata.org/prop/direct/P2579'), ('top', 'jikimiyake'), ('films', 'film studies'), ('obj', 'http://www.wikidata.org/entity/Q1660187')]
# [('P', 'http://www.wikidata.org/prop/direct/P2579'), ('top', 'war horse'), ('films', 'film studies'), ('obj', 'http://www.wikidata.org/entity/Q1660187')]
# [('P', 'http://www.wikidata.org/prop/direct/P2579'), ('top', '2010 Pacific hurricane season'), ('films', 'film studies'), ('obj', 'http://www.wikidata.org/entity/Q1660187')]
# [('P', 'http://www.wikidata.org/prop/direct/P2579'), ('top', '1972 in economics'), ('films', 'film studies'), ('obj', 'http://www.wikidata.org/entity/Q1660187')]
# [('P', 'http://www.wikidata.org/prop/direct/P2579'), ('top', '2020 Winter Youth Olympics'), ('films', 'film studies'), ('obj', 'http://www.wikidata.org/entity/Q1660187')]
# [('P', 'http://www.wikidata.org/prop/direct/P2579'), ('top', 'Hitachi Province'), ('films', 'film studies'), ('obj', 'http://www.wikidata.org/entity/Q1660187')]
# [('P', 'http://www.wikidata.org/prop/direct/P2579'), ('top', 'Lightiella'), ('films', 'film studies'), ('obj', 'http://www.wikidata.org/entity/Q1660187')]
# [('P', 'http://www.wikidata.org/prop/direct/P2579'), ('top', 'compilation album released this year'), ('films', 'film studies'), ('obj', 'http://www.wikidata.org/entity/Q1660187')]
# [('P', 'http://www.wikidata.org/prop/direct/P2579'), ('top', 'region of Ethiopia'), ('films', 'film studies'), ('obj', 'http://www.wikidata.org/entity/Q1660187')]
# [('P', 'http://www.wikidata.org/prop/direct/P2579'), ('top', 'Mateo Egea'), ('films', 'film studies'), ('obj', 'http://www.wikidata.org/entity/Q1660187')]
# [('P', 'http://www.wikidata.org/prop/direct/P2579'), ('top', '1942 in meteorology'), ('films', 'film studies'), ('obj', 'http://www.wikidata.org/entity/Q1660187')]
# [('P', 'http://www.wikidata.org/prop/direct/P2579'), ('top', '1958 in meteorology'), ('films', 'film studies'), ('obj', 'http://www.wikidata.org/entity/Q1660187')]
# [('P', 'http://www.wikidata.org/prop/direct/P2579'), ('top', '1964 in meteorology'), ('films', 'film studies'), ('obj', 'http://www.wikidata.org/entity/Q1660187')]
# [('P', 'http://www.wikidata.org/prop/direct/P2579'), ('top', '1971 in meteorology'), ('films', 'film studies'), ('obj', 'http://www.wikidata.org/entity/Q1660187')]
# [('P', 'http://www.wikidata.org/prop/direct/P2579'), ('top', '1989 in meteorology'), ('films', 'film studies'), ('obj', 'http://www.wikidata.org/entity/Q1660187')]
# [('P', 'http://www.wikidata.org/prop/direct/P2579'), ('top', '2000 in meteorology'), ('films', 'film studies'), ('obj', 'http://www.wikidata.org/entity/Q1660187')]
# [('P', 'http://www.wikidata.org/prop/direct/P2579'), ('top', '2003 in meteorology'), ('films', 'film studies'), ('obj', 'http://www.wikidata.org/entity/Q1660187')]
# [('P', 'http://www.wikidata.org/prop/direct/P2579'), ('top', 'Nemėžis'), ('films', 'film studies'), ('obj', 'http://www.wikidata.org/entity/Q1660187')]
# [('P', 'http://www.wikidata.org/prop/direct/P2579'), ('top', '530 BC'), ('films', 'film studies'), ('obj', 'http://www.wikidata.org/entity/Q1660187')]
# [('P', 'http://www.wikidata.org/prop/direct/P2579'), ('top', 'ambassador of China to Peru'), ('films', 'film studies'), ('obj', 'http://www.wikidata.org/entity/Q1660187')]
# [('P', 'http://www.wikidata.org/prop/direct/P2579'), ('top', 'Pleomothra'), ('films', 'film studies'), ('obj', 'http://www.wikidata.org/entity/Q1660187')]
# 50

# %%
#now we have to filter out academy awards
queryString = """
SELECT DISTINCT ?P ?top ?films ?obj
WHERE {
   # bind something
    # ?P wdt:P166 ?obj.
   #get the label
   # ?p sc:name ?top.
   FILTER(REGEX(?top,"Academy Award"^^xsd:))
   }
   
LIMIT 50
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('P', 'http://www.wikidata.org/entity/Q8201073'), ('top', 'Category:Academy Award for Best Documentary Feature templates'), ('obj', 'http://www.wikidata.org/entity/Q25421476')]
# [('P', 'http://www.wikidata.org/entity/Q8201073'), ('top', 'Category:Academy Award for Best Original Song templates'), ('obj', 'http://www.wikidata.org/entity/Q25421476')]
# [('P', 'http://www.wikidata.org/entity/Q8201073'), ('top', 'Category:Films whose cinematographer won the Best Cinematography Academy Award'), ('obj', 'http://www.wikidata.org/entity/Q25421476')]
# [('P', 'http://www.wikidata.org/entity/Q8201073'), ('top', 'Africa Movie Academy Award for Best Actress in a Supporting Role'), ('obj', 'http://www.wikidata.org/entity/Q25421476')]
# [('P', 'http://www.wikidata.org/entity/Q8201073'), ('top', 'Africa Movie Academy Award for Most Promising Actor'), ('obj', 'http://www.wikidata.org/entity/Q25421476')]
# [('P', 'http://www.wikidata.org/entity/Q8201073'), ('top', '"Sunshine", "Queen" in the spotlight as 79th Annual Academy Award nominations announced'), ('obj', 'http://www.wikidata.org/entity/Q25421476')]
# [('P', 'http://www.wikidata.org/entity/Q8201073'), ('top', "'Aviator,' 'Baby' dominate 2005 Academy Awards"), ('obj', 'http://www.wikidata.org/entity/Q25421476')]
# [('P', 'http://www.wikidata.org/entity/Q8201073'), ('top', 'Elton John AIDS Foundation Party to mark the 2007 Academy Awards'), ('obj', 'http://www.wikidata.org/entity/Q25421476')]
# [('P', 'http://www.wikidata.org/entity/Q8201073'), ('top', 'list of Indian submissions for the Academy Award for Best Foreign Language Film'), ('obj', 'http://www.wikidata.org/entity/Q25421476')]
# [('P', 'http://www.wikidata.org/entity/Q8201073'), ('top', '89th Academy Awards'), ('obj', 'http://www.wikidata.org/entity/Q25421476')]
# [('P', 'http://www.wikidata.org/entity/Q8201073'), ('top', 'Category:2017 Academy Awards'), ('obj', 'http://www.wikidata.org/entity/Q25421476')]
# [('P', 'http://www.wikidata.org/entity/Q8201073'), ('top', 'Category:Best Documentary Short Subject Academy Award winners'), ('obj', 'http://www.wikidata.org/entity/Q25421476')]
# [('P', 'http://www.wikidata.org/entity/Q8201073'), ('top', 'Template:Indian Television Academy Award Most Promising Child Star'), ('obj', 'http://www.wikidata.org/entity/Q25421476')]
# [('P', 'http://www.wikidata.org/entity/Q8201073'), ('top', '16th Academy Awards'), ('obj', 'http://www.wikidata.org/entity/Q25421476')]
# [('P', 'http://www.wikidata.org/entity/Q8201073'), ('top', 'International Indian Film Academy Awards'), ('obj', 'http://www.wikidata.org/entity/Q25421476')]
# [('P', 'http://www.wikidata.org/entity/Q8201073'), ('top', '45th Academy Awards'), ('obj', 'http://www.wikidata.org/entity/Q25421476')]
# [('P', 'http://www.wikidata.org/entity/Q8201073'), ('top', '51st Academy Awards'), ('obj', 'http://www.wikidata.org/entity/Q25421476')]
# [('P', 'http://www.wikidata.org/entity/Q8201073'), ('top', 'Academy Award for Best Original Musical or Comedy Score'), ('obj', 'http://www.wikidata.org/entity/Q25421476')]
# [('P', 'http://www.wikidata.org/entity/Q8201073'), ('top', '52nd Academy Awards'), ('obj', 'http://www.wikidata.org/entity/Q25421476')]
# [('P', 'http://www.wikidata.org/entity/Q8201073'), ('top', 'Polish Academy Award for Best Costume Design'), ('obj', 'http://www.wikidata.org/entity/Q25421476')]
# [('P', 'http://www.wikidata.org/entity/Q8201073'), ('top', '1929 Academy Awards'), ('obj', 'http://www.wikidata.org/entity/Q25421476')]
# [('P', 'http://www.wikidata.org/entity/Q8201073'), ('top', '1946 Academy Awards'), ('obj', 'http://www.wikidata.org/entity/Q25421476')]
# [('P', 'http://www.wikidata.org/entity/Q8201073'), ('top', '1978 Academy Awards'), ('obj', 'http://www.wikidata.org/entity/Q25421476')]
# [('P', 'http://www.wikidata.org/entity/Q8201073'), ('top', '1981 Academy Awards'), ('obj', 'http://www.wikidata.org/entity/Q25421476')]
# [('P', 'http://www.wikidata.org/entity/Q8201073'), ('top', '1988 Academy Awards'), ('obj', 'http://www.wikidata.org/entity/Q25421476')]
# [('P', 'http://www.wikidata.org/entity/Q8201073'), ('top', '2001 Academy Awards'), ('obj', 'http://www.wikidata.org/entity/Q25421476')]
# [('P', 'http://www.wikidata.org/entity/Q8201073'), ('top', 'Comedian Jon Stewart to host 78th Academy Awards'), ('obj', 'http://www.wikidata.org/entity/Q25421476')]
# [('P', 'http://www.wikidata.org/entity/Q8201073'), ('top', 'Nominations announced for 78th Academy Awards'), ('obj', 'http://www.wikidata.org/entity/Q25421476')]
# [('P', 'http://www.wikidata.org/entity/Q8201073'), ('top', 'Africa Movie Academy Award for Best Cinematography'), ('obj', 'http://www.wikidata.org/entity/Q25421476')]
# [('P', 'http://www.wikidata.org/entity/Q8201073'), ('top', 'Africa Movie Academy Award for Best Costume Design'), ('obj', 'http://www.wikidata.org/entity/Q25421476')]
# [('P', 'http://www.wikidata.org/entity/Q8201073'), ('top', 'Student Academy Awards'), ('obj', 'http://www.wikidata.org/entity/Q25421476')]
# [('P', 'http://www.wikidata.org/entity/Q8201073'), ('top', 'Academy Award for Best Cinematography, Color'), ('obj', 'http://www.wikidata.org/entity/Q25421476')]
# [('P', 'http://www.wikidata.org/entity/Q8201073'), ('top', 'Academy Award for Best Cinematography, Black-and-White'), ('obj', 'http://www.wikidata.org/entity/Q25421476')]
# [('P', 'http://www.wikidata.org/entity/Q8201073'), ('top', 'Academy Award for Best Art Direction, Color'), ('obj', 'http://www.wikidata.org/entity/Q25421476')]
# [('P', 'http://www.wikidata.org/entity/Q8201073'), ('top', 'Academy Award for Best Score, Adaptation or Treatment'), ('obj', 'http://www.wikidata.org/entity/Q25421476')]
# [('P', 'http://www.wikidata.org/entity/Q8201073'), ('top', 'Academy Award for Best Live Action Short Film'), ('obj', 'http://www.wikidata.org/entity/Q25421476')]
# [('P', 'http://www.wikidata.org/entity/Q8201073'), ('top', 'Academy Award for Best Makeup and Hairstyling'), ('obj', 'http://www.wikidata.org/entity/Q25421476')]
# [('P', 'http://www.wikidata.org/entity/Q8201073'), ('top', 'Academy Award for Best Story'), ('obj', 'http://www.wikidata.org/entity/Q25421476')]
# [('P', 'http://www.wikidata.org/entity/Q8201073'), ('top', 'Academy Award for Best Short Subject, Novelty'), ('obj', 'http://www.wikidata.org/entity/Q25421476')]
# [('P', 'http://www.wikidata.org/entity/Q8201073'), ('top', 'Academy Award for Best Documentary (Short Subject)'), ('obj', 'http://www.wikidata.org/entity/Q25421476')]
# [('P', 'http://www.wikidata.org/entity/Q8201073'), ('top', 'Academy Award for Best Animated Short Film'), ('obj', 'http://www.wikidata.org/entity/Q25421476')]
# [('P', 'http://www.wikidata.org/entity/Q8201073'), ('top', 'Academy Award for Best Original Score, no Musical'), ('obj', 'http://www.wikidata.org/entity/Q25421476')]
# [('P', 'http://www.wikidata.org/entity/Q8201073'), ('top', 'Academy Award for Best Live Action Short Film, Comedy'), ('obj', 'http://www.wikidata.org/entity/Q25421476')]
# [('P', 'http://www.wikidata.org/entity/Q8201073'), ('top', 'Academy Award for Best Director, Dramatic Picture'), ('obj', 'http://www.wikidata.org/entity/Q25421476')]
# [('P', 'http://www.wikidata.org/entity/Q8201073'), ('top', '57th Academy Awards'), ('obj', 'http://www.wikidata.org/entity/Q25421476')]
# [('P', 'http://www.wikidata.org/entity/Q8201073'), ('top', '58th Academy Awards'), ('obj', 'http://www.wikidata.org/entity/Q25421476')]
# [('P', 'http://www.wikidata.org/entity/Q8201073'), ('top', '90th Academy Awards'), ('obj', 'http://www.wikidata.org/entity/Q25421476')]
# [('P', 'http://www.wikidata.org/entity/Q8201073'), ('top', 'Academy Award of the Hungarian Academy of Sciences'), ('obj', 'http://www.wikidata.org/entity/Q25421476')]
# [('P', 'http://www.wikidata.org/entity/Q8201073'), ('top', 'Special Achievement Academy Award'), ('obj', 'http://www.wikidata.org/entity/Q25421476')]
# [('P', 'http://www.wikidata.org/entity/Q8201073'), ('top', '14th Academy Awards'), ('obj', 'http://www.wikidata.org/entity/Q25421476')]
# 50

# %%
# write your final query
#now we have to filter out academy awards with respect to object
queryString = """
SELECT DISTINCT ?P ?top ?films ?obj
WHERE {
   # bind something
    # ?P wdt:P166 ?obj.
   #get the label
   # ?obj sc:name ?top.
   FILTER(REGEX(?top,"Academy Award"^^xsd:))
   }
   
LIMIT 50
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('P', 'http://www.wikidata.org/entity/Q231276'), ('top', 'Africa Movie Academy Award for Best Actress in a Supporting Role'), ('obj', 'http://www.wikidata.org/entity/Q17001892')]
# [('P', 'http://www.wikidata.org/entity/Q16194334'), ('top', 'Africa Movie Academy Award for Best Actress in a Supporting Role'), ('obj', 'http://www.wikidata.org/entity/Q17001892')]
# [('P', 'http://www.wikidata.org/entity/Q8062489'), ('top', 'Africa Movie Academy Award for Best Actress in a Supporting Role'), ('obj', 'http://www.wikidata.org/entity/Q17001892')]
# [('P', 'http://www.wikidata.org/entity/Q24289792'), ('top', 'Africa Movie Academy Award for Best Actress in a Supporting Role'), ('obj', 'http://www.wikidata.org/entity/Q17001892')]
# [('P', 'http://www.wikidata.org/entity/Q13638782'), ('top', 'Africa Movie Academy Award for Best Actress in a Supporting Role'), ('obj', 'http://www.wikidata.org/entity/Q17001892')]
# [('P', 'http://www.wikidata.org/entity/Q24572815'), ('top', 'Africa Movie Academy Award for Best Actress in a Supporting Role'), ('obj', 'http://www.wikidata.org/entity/Q17001892')]
# [('P', 'http://www.wikidata.org/entity/Q16832217'), ('top', 'Africa Movie Academy Award for Most Promising Actor'), ('obj', 'http://www.wikidata.org/entity/Q17001922')]
# [('P', 'http://www.wikidata.org/entity/Q24577229'), ('top', 'Africa Movie Academy Award for Most Promising Actor'), ('obj', 'http://www.wikidata.org/entity/Q17001922')]
# [('P', 'http://www.wikidata.org/entity/Q504191'), ('top', '16th Academy Awards'), ('obj', 'http://www.wikidata.org/entity/Q148609')]
# [('P', 'http://www.wikidata.org/entity/Q708870'), ('top', '16th Academy Awards'), ('obj', 'http://www.wikidata.org/entity/Q148609')]
# [('P', 'http://www.wikidata.org/entity/Q732397'), ('top', 'International Indian Film Academy Awards'), ('obj', 'http://www.wikidata.org/entity/Q655089')]
# [('P', 'http://www.wikidata.org/entity/Q2573055'), ('top', 'International Indian Film Academy Awards'), ('obj', 'http://www.wikidata.org/entity/Q655089')]
# [('P', 'http://www.wikidata.org/entity/Q2087610'), ('top', 'International Indian Film Academy Awards'), ('obj', 'http://www.wikidata.org/entity/Q655089')]
# [('P', 'http://www.wikidata.org/entity/Q489951'), ('top', '45th Academy Awards'), ('obj', 'http://www.wikidata.org/entity/Q918125')]
# [('P', 'http://www.wikidata.org/entity/Q261314'), ('top', 'Academy Award for Best Original Musical or Comedy Score'), ('obj', 'http://www.wikidata.org/entity/Q22235305')]
# [('P', 'http://www.wikidata.org/entity/Q317272'), ('top', 'Academy Award for Best Original Musical or Comedy Score'), ('obj', 'http://www.wikidata.org/entity/Q22235305')]
# [('P', 'http://www.wikidata.org/entity/Q542484'), ('top', 'Academy Award for Best Original Musical or Comedy Score'), ('obj', 'http://www.wikidata.org/entity/Q22235305')]
# [('P', 'http://www.wikidata.org/entity/Q1361541'), ('top', 'Academy Award for Best Original Musical or Comedy Score'), ('obj', 'http://www.wikidata.org/entity/Q22235305')]
# [('P', 'http://www.wikidata.org/entity/Q273502'), ('top', 'Academy Award for Best Original Musical or Comedy Score'), ('obj', 'http://www.wikidata.org/entity/Q22235305')]
# [('P', 'http://www.wikidata.org/entity/Q218894'), ('top', 'Academy Award for Best Original Musical or Comedy Score'), ('obj', 'http://www.wikidata.org/entity/Q22235305')]
# [('P', 'http://www.wikidata.org/entity/Q775970'), ('top', 'Academy Award for Best Original Musical or Comedy Score'), ('obj', 'http://www.wikidata.org/entity/Q22235305')]
# [('P', 'http://www.wikidata.org/entity/Q1338008'), ('top', 'Academy Award for Best Original Musical or Comedy Score'), ('obj', 'http://www.wikidata.org/entity/Q22235305')]
# [('P', 'http://www.wikidata.org/entity/Q182944'), ('top', 'Academy Award for Best Original Musical or Comedy Score'), ('obj', 'http://www.wikidata.org/entity/Q22235305')]
# [('P', 'http://www.wikidata.org/entity/Q21288229'), ('top', 'Polish Academy Award for Best Costume Design'), ('obj', 'http://www.wikidata.org/entity/Q547575')]
# [('P', 'http://www.wikidata.org/entity/Q9210238'), ('top', 'Polish Academy Award for Best Costume Design'), ('obj', 'http://www.wikidata.org/entity/Q547575')]
# [('P', 'http://www.wikidata.org/entity/Q20640094'), ('top', 'Polish Academy Award for Best Costume Design'), ('obj', 'http://www.wikidata.org/entity/Q547575')]
# [('P', 'http://www.wikidata.org/entity/Q585823'), ('top', 'Polish Academy Award for Best Costume Design'), ('obj', 'http://www.wikidata.org/entity/Q547575')]
# [('P', 'http://www.wikidata.org/entity/Q9153714'), ('top', 'Polish Academy Award for Best Costume Design'), ('obj', 'http://www.wikidata.org/entity/Q547575')]
# [('P', 'http://www.wikidata.org/entity/Q11721328'), ('top', 'Polish Academy Award for Best Costume Design'), ('obj', 'http://www.wikidata.org/entity/Q547575')]
# [('P', 'http://www.wikidata.org/entity/Q11766007'), ('top', 'Polish Academy Award for Best Costume Design'), ('obj', 'http://www.wikidata.org/entity/Q547575')]
# [('P', 'http://www.wikidata.org/entity/Q11766110'), ('top', 'Polish Academy Award for Best Costume Design'), ('obj', 'http://www.wikidata.org/entity/Q547575')]
# [('P', 'http://www.wikidata.org/entity/Q1095425'), ('top', 'Polish Academy Award for Best Costume Design'), ('obj', 'http://www.wikidata.org/entity/Q547575')]
# [('P', 'http://www.wikidata.org/entity/Q103988746'), ('top', 'Polish Academy Award for Best Costume Design'), ('obj', 'http://www.wikidata.org/entity/Q547575')]
# [('P', 'http://www.wikidata.org/entity/Q57699425'), ('top', 'Africa Movie Academy Award for Best Cinematography'), ('obj', 'http://www.wikidata.org/entity/Q18204254')]
# [('P', 'http://www.wikidata.org/entity/Q6509232'), ('top', 'Student Academy Awards'), ('obj', 'http://www.wikidata.org/entity/Q375039')]
# [('P', 'http://www.wikidata.org/entity/Q67915808'), ('top', 'Student Academy Awards'), ('obj', 'http://www.wikidata.org/entity/Q375039')]
# [('P', 'http://www.wikidata.org/entity/Q7496448'), ('top', 'Student Academy Awards'), ('obj', 'http://www.wikidata.org/entity/Q375039')]
# [('P', 'http://www.wikidata.org/entity/Q1699139'), ('top', 'Academy Award for Best Cinematography, Color'), ('obj', 'http://www.wikidata.org/entity/Q21995136')]
# [('P', 'http://www.wikidata.org/entity/Q504191'), ('top', 'Academy Award for Best Cinematography, Color'), ('obj', 'http://www.wikidata.org/entity/Q21995136')]
# [('P', 'http://www.wikidata.org/entity/Q568941'), ('top', 'Academy Award for Best Cinematography, Color'), ('obj', 'http://www.wikidata.org/entity/Q21995136')]
# [('P', 'http://www.wikidata.org/entity/Q606928'), ('top', 'Academy Award for Best Cinematography, Color'), ('obj', 'http://www.wikidata.org/entity/Q21995136')]
# [('P', 'http://www.wikidata.org/entity/Q436704'), ('top', 'Academy Award for Best Cinematography, Color'), ('obj', 'http://www.wikidata.org/entity/Q21995136')]
# [('P', 'http://www.wikidata.org/entity/Q657828'), ('top', 'Academy Award for Best Cinematography, Color'), ('obj', 'http://www.wikidata.org/entity/Q21995136')]
# [('P', 'http://www.wikidata.org/entity/Q1706396'), ('top', 'Academy Award for Best Cinematography, Color'), ('obj', 'http://www.wikidata.org/entity/Q21995136')]
# [('P', 'http://www.wikidata.org/entity/Q323827'), ('top', 'Academy Award for Best Cinematography, Color'), ('obj', 'http://www.wikidata.org/entity/Q21995136')]
# [('P', 'http://www.wikidata.org/entity/Q1346696'), ('top', 'Academy Award for Best Cinematography, Color'), ('obj', 'http://www.wikidata.org/entity/Q21995136')]
# [('P', 'http://www.wikidata.org/entity/Q210873'), ('top', 'Academy Award for Best Cinematography, Color'), ('obj', 'http://www.wikidata.org/entity/Q21995136')]
# [('P', 'http://www.wikidata.org/entity/Q1217612'), ('top', 'Academy Award for Best Cinematography, Color'), ('obj', 'http://www.wikidata.org/entity/Q21995136')]
# [('P', 'http://www.wikidata.org/entity/Q607280'), ('top', 'Academy Award for Best Cinematography, Color'), ('obj', 'http://www.wikidata.org/entity/Q21995136')]
# [('P', 'http://www.wikidata.org/entity/Q645627'), ('top', 'Academy Award for Best Cinematography, Color'), ('obj', 'http://www.wikidata.org/entity/Q21995136')]
# 50

# %%
# here we further explore 45th academy awards 
#[('P', 'http://www.wikidata.org/entity/Q489951'), ('top', '45th Academy Awards'),
queryString = """
SELECT DISTINCT ?P ?top ?films ?obj
WHERE {
   # bind something
   wd:Q489951 ?P ?obj.
   #get the label
   # ?obj sc:name ?top.
   FILTER(REGEX(?top,"Academy Award"^^xsd:))
   }
   
LIMIT 50
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('P', 'http://www.wikidata.org/prop/direct/P166'), ('top', '45th Academy Awards'), ('obj', 'http://www.wikidata.org/entity/Q918125')]
# [('P', 'http://www.wikidata.org/prop/direct/P1411'), ('top', 'Academy Award for Best Cinematography, Color'), ('obj', 'http://www.wikidata.org/entity/Q21995136')]
# [('P', 'http://www.wikidata.org/prop/direct/P166'), ('top', 'Academy Awards'), ('obj', 'http://www.wikidata.org/entity/Q19020')]
# [('P', 'http://www.wikidata.org/prop/direct/P1411'), ('top', 'Academy Award for Best Cinematography'), ('obj', 'http://www.wikidata.org/entity/Q131520')]
# [('P', 'http://www.wikidata.org/prop/direct/P166'), ('top', 'Academy Award for Best Cinematography'), ('obj', 'http://www.wikidata.org/entity/Q131520')]
# [('P', 'http://www.wikidata.org/prop/direct/P166'), ('top', '53rd Academy Awards'), ('obj', 'http://www.wikidata.org/entity/Q767355')]
# 6

# %%
#FINAL QUERY
#BGP FOR ACADEMY AWARDS
#[('P', 'http://www.wikidata.org/prop/direct/P166'), ('top', 'Academy Awards'), ('obj', 'http://www.wikidata.org/entity/Q19020')]
queryString = """
SELECT DISTINCT ?P ?top ?films ?obj
WHERE {
   # bind something
   wd:Q19020 ?P ?obj.
   #get the label
   # ?obj sc:name ?top.
   #FILTER(REGEX(?top,"Academy Award"^^xsd:))
   }
   
LIMIT 50
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('P', 'http://www.wikidata.org/prop/direct/P527'), ('top', 'Academy Award for Best Picture'), ('obj', 'http://www.wikidata.org/entity/Q102427')]
# [('P', 'http://www.wikidata.org/prop/direct/P527'), ('top', 'Academy Award for Best Director'), ('obj', 'http://www.wikidata.org/entity/Q103360')]
# [('P', 'http://www.wikidata.org/prop/direct/P527'), ('top', 'Academy Award for Best Actress'), ('obj', 'http://www.wikidata.org/entity/Q103618')]
# [('P', 'http://www.wikidata.org/prop/direct/P527'), ('top', 'Academy Award for Best Supporting Actress'), ('obj', 'http://www.wikidata.org/entity/Q106301')]
# [('P', 'http://www.wikidata.org/prop/direct/P527'), ('top', 'Academy Award for Best Writing, Adapted Screenplay'), ('obj', 'http://www.wikidata.org/entity/Q107258')]
# [('P', 'http://www.wikidata.org/prop/direct/P527'), ('top', 'Academy Award for Best Original Song'), ('obj', 'http://www.wikidata.org/entity/Q112243')]
# [('P', 'http://www.wikidata.org/prop/direct/P17'), ('top', 'United States of America'), ('obj', 'http://www.wikidata.org/entity/Q30')]
# [('P', 'http://www.wikidata.org/prop/direct/P527'), ('top', 'Academy Award for Best Writing, Original Screenplay'), ('obj', 'http://www.wikidata.org/entity/Q41417')]
# [('P', 'http://www.wikidata.org/prop/direct/P527'), ('top', 'Academy Award for Best Actor'), ('obj', 'http://www.wikidata.org/entity/Q103916')]
# [('P', 'http://www.wikidata.org/prop/direct/P527'), ('top', 'Academy Award for Best Foreign Language Film'), ('obj', 'http://www.wikidata.org/entity/Q105304')]
# [('P', 'http://www.wikidata.org/prop/direct/P527'), ('top', 'Academy Award for Best Supporting Actor'), ('obj', 'http://www.wikidata.org/entity/Q106291')]
# [('P', 'http://www.wikidata.org/prop/direct/P31'), ('top', 'group of awards'), ('obj', 'http://www.wikidata.org/entity/Q107655869')]
# [('P', 'http://www.wikidata.org/prop/direct/P527'), ('top', 'Academy Award for Best Cinematography'), ('obj', 'http://www.wikidata.org/entity/Q131520')]
# [('P', 'http://www.wikidata.org/prop/direct/P527'), ('top', 'Academy Award for Best Costume Design'), ('obj', 'http://www.wikidata.org/entity/Q277536')]
# [('P', 'http://www.wikidata.org/prop/direct/P279'), ('top', 'film award'), ('obj', 'http://www.wikidata.org/entity/Q4220917')]
# [('P', 'http://www.wikidata.org/prop/direct/P527'), ('top', 'Academy Award for Best Original Score'), ('obj', 'http://www.wikidata.org/entity/Q488651')]
# [('P', 'http://www.wikidata.org/prop/direct/P527'), ('top', 'Academy Award for Best Animated Feature'), ('obj', 'http://www.wikidata.org/entity/Q106800')]
# [('P', 'http://www.wikidata.org/prop/direct/P1889'), ('top', 'Academy Awards ceremony'), ('obj', 'http://www.wikidata.org/entity/Q16913666')]
# [('P', 'http://www.wikidata.org/prop/direct/P1027'), ('top', 'Academy of Motion Picture Arts and Sciences'), ('obj', 'http://www.wikidata.org/entity/Q212329')]
# [('P', 'http://www.wikidata.org/prop/direct/P527'), ('top', 'Academy Award for Best Original Dramatic Score'), ('obj', 'http://www.wikidata.org/entity/Q22235329')]
# [('P', 'http://www.wikidata.org/prop/direct/P527'), ('top', 'Academy Award for Best Documentary Feature'), ('obj', 'http://www.wikidata.org/entity/Q111332')]
# [('P', 'http://www.wikidata.org/prop/direct/P1343'), ('top', 'Disney A to Z'), ('obj', 'http://www.wikidata.org/entity/Q3710090')]
# [('P', 'http://www.wikidata.org/prop/direct/P1889'), ('top', 'Academy Award'), ('obj', 'http://www.wikidata.org/entity/Q4671334')]
# [('P', 'http://www.wikidata.org/prop/direct/P2517'), ('top', 'Category:Academy Award winners'), ('obj', 'http://www.wikidata.org/entity/Q6468204')]
# [('P', 'http://www.wikidata.org/prop/direct/P527'), ('top', 'Academy Award for Best Director (Comedy picture)'), ('obj', 'http://www.wikidata.org/entity/Q3451157')]
# [('P', 'http://www.wikidata.org/prop/direct/P1424'), ('top', 'Template:Academy Awards'), ('obj', 'http://www.wikidata.org/entity/Q5483199')]
# [('P', 'http://www.wikidata.org/prop/direct/P910'), ('top', 'Category:Academy Awards'), ('obj', 'http://www.wikidata.org/entity/Q7148118')]
# [('P', 'http://www.wikidata.org/prop/direct/P4622'), ('top', 'Oscar statuette'), ('obj', 'http://www.wikidata.org/entity/Q11291954')]
# [('P', 'http://www.wikidata.org/prop/direct/P1424'), ('top', 'Template:Infobox Academy Awards'), ('obj', 'http://www.wikidata.org/entity/Q13361762')]
# [('P', 'http://www.wikidata.org/prop/direct/P1889'), ('top', 'Óscar'), ('obj', 'http://www.wikidata.org/entity/Q21475960')]
# 30

# %% [markdown]
# ## Task 9
# Find the companies (among television and film production companies) that won at least 5 Academy Awards for Best Actress for the movies they produced (the result set must be a list of triples company IRI, label and #awards).

# %%
# write your queries
#USING CATEGORY OF ACADEMY AWARS WINNERS

#[('P', 'http://www.wikidata.org/prop/direct/P2517'),
queryString = """
SELECT DISTINCT ?P ?top ?films ?obj
WHERE {
   # bind something
   wd:Q19020 wdt:P2517 ?obj.
   #get the label
   # ?obj sc:name ?top.
   #FILTER(REGEX(?top,"Academy Award"^^xsd:))
   }
   
LIMIT 50
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('top', 'Category:Academy Award winners'), ('obj', 'http://www.wikidata.org/entity/Q6468204')]
# 1

# %%
#[('top', 'Category:Academy Award winners'), ('obj', 'http://www.wikidata.org/entity/Q6468204')]
queryString = """
SELECT DISTINCT ?P ?top ?films ?obj
WHERE {
   # bind something
   wd:Q6468204 ?P ?obj.
   #get the label
   # ?obj sc:name ?top.
   #FILTER(REGEX(?top,"Academy Award"^^xsd:))
   }
   
LIMIT 50
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('P', 'http://www.wikidata.org/prop/direct/P971'), ('top', 'award winner'), ('obj', 'http://www.wikidata.org/entity/Q21096945')]
# [('P', 'http://www.wikidata.org/prop/direct/P971'), ('top', 'Academy Awards'), ('obj', 'http://www.wikidata.org/entity/Q19020')]
# [('P', 'http://www.wikidata.org/prop/direct/P31'), ('top', 'Wikimedia category'), ('obj', 'http://www.wikidata.org/entity/Q4167836')]
# [('P', 'http://www.wikidata.org/prop/direct/P4224'), ('top', 'human'), ('obj', 'http://www.wikidata.org/entity/Q5')]
# 4

# %%
#all award winners
#[('P', 'http://www.wikidata.org/prop/direct/P971'), ('top', 'award winner'),
#[('top', 'Category:Academy Award winners'), ('obj', 'http://www.wikidata.org/entity/Q6468204')]
queryString = """
SELECT DISTINCT ?P ?top ?films ?obj
WHERE {
   # bind something
   # ?p wdt:P971 ?obj.
   #get the label
   # ?obj sc:name ?top.
   #FILTER(REGEX(?top,"Academy Award"^^xsd:))
   }
   
LIMIT 50
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('top', 'Category:1920 elections in Oceania'), ('obj', 'http://www.wikidata.org/entity/Q10145708')]
# [('top', 'Category:2002 elections in South America'), ('obj', 'http://www.wikidata.org/entity/Q10147007')]
# [('top', 'Category:Akita Shoten magazines'), ('obj', 'http://www.wikidata.org/entity/Q10237146')]
# [('top', 'Category:2009 in Australian sport'), ('obj', 'http://www.wikidata.org/entity/Q11167612')]
# [('top', 'Category:1981 in New Zealand sport'), ('obj', 'http://www.wikidata.org/entity/Q11721574')]
# [('top', 'Category:1926 in Argentine sport'), ('obj', 'http://www.wikidata.org/entity/Q13237425')]
# [('top', 'Category:1928 in Argentine sport'), ('obj', 'http://www.wikidata.org/entity/Q13237485')]
# [('top', 'Category:1928 in South American sport'), ('obj', 'http://www.wikidata.org/entity/Q13237495')]
# [('top', 'Category:1932 in table tennis'), ('obj', 'http://www.wikidata.org/entity/Q13237669')]
# [('top', 'Category:1944 in Antarctica'), ('obj', 'http://www.wikidata.org/entity/Q13238087')]
# [('top', 'Category:1955 in swimming'), ('obj', 'http://www.wikidata.org/entity/Q13238540')]
# [('top', 'Category:1964 in English sport'), ('obj', 'http://www.wikidata.org/entity/Q13238939')]
# [('top', 'Category:1971 in Central American sport'), ('obj', 'http://www.wikidata.org/entity/Q13239271')]
# [('top', 'Category:1971 in bobsleigh'), ('obj', 'http://www.wikidata.org/entity/Q13239287')]
# [('top', 'Category:1973 in bobsleigh'), ('obj', 'http://www.wikidata.org/entity/Q13239384')]
# [('top', 'Category:1976 in Hawaii'), ('obj', 'http://www.wikidata.org/entity/Q13239542')]
# [('top', 'Category:1977 in Belgian sport'), ('obj', 'http://www.wikidata.org/entity/Q13239595')]
# [('top', 'Category:1982 in ski jumping'), ('obj', 'http://www.wikidata.org/entity/Q13239894')]
# [('top', 'Category:1988 in Canadian sports'), ('obj', 'http://www.wikidata.org/entity/Q13240187')]
# [('top', 'Category:1989 in bobsleigh'), ('obj', 'http://www.wikidata.org/entity/Q13240245')]
# [('top', 'Category:1991 in German sport'), ('obj', 'http://www.wikidata.org/entity/Q13240372')]
# [('top', 'Category:1994 in Swiss sport'), ('obj', 'http://www.wikidata.org/entity/Q13240562')]
# [('top', 'Category:1994 in bobsleigh'), ('obj', 'http://www.wikidata.org/entity/Q13240568')]
# [('top', 'Category:1995 in water polo'), ('obj', 'http://www.wikidata.org/entity/Q13240638')]
# [('top', 'Category:2006 elections in North America'), ('obj', 'http://www.wikidata.org/entity/Q13241549')]
# [('top', 'Category:2006 in Swedish association football leagues'), ('obj', 'http://www.wikidata.org/entity/Q13241605')]
# [('top', 'Category:2009 in English sport'), ('obj', 'http://www.wikidata.org/entity/Q13241911')]
# [('top', 'Category:2015 in table tennis'), ('obj', 'http://www.wikidata.org/entity/Q13242423')]
# [('top', 'Category:Airlines disestablished in 1983'), ('obj', 'http://www.wikidata.org/entity/Q13243867')]
# [('top', 'Category:2013 in table tennis'), ('obj', 'http://www.wikidata.org/entity/Q13316531')]
# [('top', 'Category:1971 in Canadian sports'), ('obj', 'http://www.wikidata.org/entity/Q13347381')]
# [('top', 'Category:1973 in Canadian sports'), ('obj', 'http://www.wikidata.org/entity/Q13347382')]
# [('top', 'Category:1994 in Canadian sports'), ('obj', 'http://www.wikidata.org/entity/Q13347390')]
# [('top', 'Category:2003 in Canadian sports'), ('obj', 'http://www.wikidata.org/entity/Q13347393')]
# [('top', 'Category:2013 in British sport'), ('obj', 'http://www.wikidata.org/entity/Q13347473')]
# [('top', 'Category:1944 in American sports'), ('obj', 'http://www.wikidata.org/entity/Q13347547')]
# [('top', 'Category:2017 in the United Kingdom'), ('obj', 'http://www.wikidata.org/entity/Q14566599')]
# [('top', 'Category:2013–14 ISU Speed Skating World Cup'), ('obj', 'http://www.wikidata.org/entity/Q14594590')]
# [('top', 'Category:18th century in Malta'), ('obj', 'http://www.wikidata.org/entity/Q15097765')]
# [('top', 'Category:1919 in Hawaii'), ('obj', 'http://www.wikidata.org/entity/Q15102953')]
# [('top', 'Category:1934 in American sports'), ('obj', 'http://www.wikidata.org/entity/Q15105200')]
# [('top', 'Category:1938 in Algeria'), ('obj', 'http://www.wikidata.org/entity/Q15106039')]
# [('top', 'Category:1944 in Italian sport'), ('obj', 'http://www.wikidata.org/entity/Q15107613')]
# [('top', 'Category:1947 in Argentine sport'), ('obj', 'http://www.wikidata.org/entity/Q15108638')]
# [('top', 'Category:1952 domestic association football leagues'), ('obj', 'http://www.wikidata.org/entity/Q15110843')]
# [('top', 'Category:1959 in Swedish sport'), ('obj', 'http://www.wikidata.org/entity/Q15113759')]
# [('top', 'Category:1963 in Hawaii'), ('obj', 'http://www.wikidata.org/entity/Q15115446')]
# [('top', 'Category:1973 in Hawaii'), ('obj', 'http://www.wikidata.org/entity/Q15117976')]
# [('top', 'Category:1981 in go'), ('obj', 'http://www.wikidata.org/entity/Q15120313')]
# [('top', 'Category:1982 in table tennis'), ('obj', 'http://www.wikidata.org/entity/Q15120435')]
# 50

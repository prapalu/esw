# %% [markdown]
# # General instructions
#
# The goal of the project is to materialize a set of **exploratory workloads** over a real-world, large-scale,  open-domain KG: [WikiData](https://www.wikidata.org/wiki/Wikidata:Main_Page)
#
# An exploratory workload  is composed by a set of queries, where each query is related to the information obtained previously.
#
# An exploratory workload starts with a usually vague, open ended question, and does not assume the person issuing the workload has a clear understanding of the data contained in the target database or its structure.
#
# Remeber that:
#
# 1. All the queries must run in the python notebook
# 2. You can use classes and properties only if you find them via a SPARQL query that must be present in the notebook
# 3. You do not delete useless queries. Keep everything that is synthatically valid
#
# ```
# ?p <http://schema.org/name> ?name .
# ```
#
#     is the BGP returning a human-readable name of a property or a class in Wikidata.

# %%
## SETUP used later

from SPARQLWrapper import SPARQLWrapper, JSON


prefixString = """
##-f457feb412-##
PREFIX wd: <http://www.wikidata.org/entity/> 
PREFIX wdt: <http://www.wikidata.org/prop/direct/> 
PREFIX sc: <http://schema.org/>
"""

# select and construct queries
def run_query(queryString,verbose = True):
    to_run = prefixString + "\n" + queryString

    sparql = SPARQLWrapper("http://a256-gc1-03.srv.aau.dk:5820/sparql")
    sparql.setTimeout(300)
    sparql.setReturnFormat(JSON)
    sparql.setQuery(to_run)

    try :
        results = sparql.query()
        json_results = results.convert()
        if len(json_results['results']['bindings'])==0:
            print("Empty")
            return []
        array = []
        for bindings in json_results['results']['bindings']:
            app =  [ (var, value['value'])  for var, value in bindings.items() ] 
            if verbose:
                print( app)
            array.append(app)
        if verbose:
            print(len(array))
        return array

    except Exception as e :
        print("The operation failed", e)
    
# ASk queries
def run_ask_query(queryString):
    to_run = prefixString + "\n" + queryString

    sparql = SPARQLWrapper("http://a256-gc1-03.srv.aau.dk:5820/sparql")
    sparql.setTimeout(300)
    sparql.setReturnFormat(JSON)
    sparql.setQuery(to_run)

    try :
        return sparql.query().convert()

    except Exception as e :
        print("The operation failed", e)

# %% [markdown]
# # Movie Workflow Series ("Film Genre and composer explorative search")
#
# Consider the following exploratory information need:
#
# > investigate the results concerning the different film genre over years and the composers for the cinema.

# %% [markdown]
# ## Useful URIs for the current workflow
# The following are given:
#
# | IRI           | Description   | Role      |
# | -----------   | -----------   |-----------|
# | `wdt:P1647`   | subproperty   | predicate |
# | `wdt:P31`     | instance of   | predicate |
# | `wdt:P106`    | occupation    | predicate |
# | `wdt:P279`    | subclass      | predicate |
# | `wdt:P27`     | nationality   | predicate |
# | `wdt:P3342`     | Significant person       | predicate |
# | `wd:Q5`| Human       | node |
# | `wd:Q25089`| Woody Allen       | node |

# %% [markdown]
# Also consider
#
# ```
# wd:Q25089 ?p ?obj .
# ```
#
# is the BGP to retrieve all **properties of Woody Allen**
#
# Please consider that when you return a resource, you should return the IRI and the label of the resource. In particular, when the task require you to identify a BGP the result set must always be a list of couples IRI - label.
#
# The workload should:
#
#
# 1. Identify the BGP for films
#
# 2. Identify the BGP for composer
#
# 3. Identify the BGP for film genre
#
# 4. Find how many films are been released in the United States of America from 2010-01-01 to 2015-31-12 for each film genre available (the result set must be genre IRI, label and #films).
#
# 5. Consider the timespan from 2001-01-01 to nowadays. Find the number of films released in this timespan divided by film genre and return only those with more than 50 films released every year (the result set must be genre IRI and label).
#
# 6. Consider the composers of Western films and their country of citizenship. Count the number of Western Films on which worked a composer grouped by country of citizenship and return the top-10 (the result set must be country IRI, label and #films)..
#
# 7. Consider the decades from 1961 to 1970, and from 2001 to 2010 and compare the total number of western films released in each one (the result set must be two couples decade and #western films of that decade).
#
# 8. Consider the decades from 1961 to 1970, and from 2001 to 2010 and select only western films. Then, for each decade, compare the average cast members size per film (the result set must be two couples decade and average cast members size of that decade).

# %% [markdown]
# ## Task 1
# Identify the BGP for films

# %% [markdown]
# Exploring Woody Allen:

# %%
queryString = """
SELECT DISTINCT ?p ?name
WHERE {
   wd:Q25089 ?p ?obj .
   # get the label
   # ?p sc:name ?name.
}
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P1003'), ('name', 'National Library of Romania ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1005'), ('name', 'Portuguese National Library ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1006'), ('name', 'Nationale Thesaurus voor Auteurs ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1015'), ('name', 'NORAF ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P103'), ('name', 'native language')]
# [('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('p', 'http://www.wikidata.org/prop/direct/P108'), ('name', 'employer')]
# [('p', 'http://www.wikidata.org/prop/direct/P109'), ('name', 'signature')]
# [('p', 'http://www.wikidata.org/prop/direct/P1150'), ('name', 'Regensburg Classification')]
# [('p', 'http://www.wikidata.org/prop/direct/P1207'), ('name', 'NUKAT ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1220'), ('name', 'Internet Broadway Database person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1233'), ('name', 'Internet Speculative Fiction Database author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1263'), ('name', 'NNDB people ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1266'), ('name', 'AlloCiné person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1273'), ('name', 'CANTIC ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1280'), ('name', 'CONOR.SI ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1283'), ('name', 'filmography')]
# [('p', 'http://www.wikidata.org/prop/direct/P1284'), ('name', 'Munzinger person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1296'), ('name', 'Gran Enciclopèdia Catalana ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1303'), ('name', 'instrument')]
# 20

# %%
queryString = """
SELECT DISTINCT ?pr ?p ?or ?o
WHERE {
   # bind something
   wd:Q25089 ?pr ?or .
   # get the label
   # ?pr sc:name ?p.
   # ?or sc:name ?o
}
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('pr', 'http://www.wikidata.org/prop/direct/P138'), ('p', 'named after'), ('or', 'http://www.wikidata.org/entity/Q349357'), ('o', 'Woody Herman')]
# [('pr', 'http://www.wikidata.org/prop/direct/P26'), ('p', 'spouse'), ('or', 'http://www.wikidata.org/entity/Q1140914'), ('o', 'Soon-Yi Previn')]
# [('pr', 'http://www.wikidata.org/prop/direct/P40'), ('p', 'child'), ('or', 'http://www.wikidata.org/entity/Q22673707'), ('o', 'Bechet Dumaine Allen')]
# [('pr', 'http://www.wikidata.org/prop/direct/P40'), ('p', 'child'), ('or', 'http://www.wikidata.org/entity/Q22673708'), ('o', 'Manzie Tio Allen')]
# [('pr', 'http://www.wikidata.org/prop/direct/P19'), ('p', 'place of birth'), ('or', 'http://www.wikidata.org/entity/Q18426'), ('o', 'The Bronx')]
# [('pr', 'http://www.wikidata.org/prop/direct/P451'), ('p', 'unmarried partner'), ('or', 'http://www.wikidata.org/entity/Q102642'), ('o', 'Diane Keaton')]
# [('pr', 'http://www.wikidata.org/prop/direct/P166'), ('p', 'award received'), ('or', 'http://www.wikidata.org/entity/Q3404523'), ('o', 'David di Donatello for Best Foreign Actor')]
# [('pr', 'http://www.wikidata.org/prop/direct/P108'), ('p', 'employer'), ('or', 'http://www.wikidata.org/entity/Q599316'), ('o', 'New School')]
# [('pr', 'http://www.wikidata.org/prop/direct/P735'), ('p', 'given name'), ('or', 'http://www.wikidata.org/entity/Q19961034'), ('o', 'Woody')]
# [('pr', 'http://www.wikidata.org/prop/direct/P800'), ('p', 'notable work'), ('or', 'http://www.wikidata.org/entity/Q206124'), ('o', 'Midnight in Paris')]
# [('pr', 'http://www.wikidata.org/prop/direct/P3373'), ('p', 'sibling'), ('or', 'http://www.wikidata.org/entity/Q3831197'), ('o', 'Letty Aronson')]
# [('pr', 'http://www.wikidata.org/prop/direct/P166'), ('p', 'award received'), ('or', 'http://www.wikidata.org/entity/Q31579'), ('o', 'David di Donatello')]
# [('pr', 'http://www.wikidata.org/prop/direct/P166'), ('p', 'award received'), ('or', 'http://www.wikidata.org/entity/Q3241784'), ('o', 'Golden Lion for Lifetime Achievements')]
# [('pr', 'http://www.wikidata.org/prop/direct/P166'), ('p', 'award received'), ('or', 'http://www.wikidata.org/entity/Q50616934'), ('o', 'honorary doctorate of Pompeu Fabra University')]
# [('pr', 'http://www.wikidata.org/prop/direct/P166'), ('p', 'award received'), ('or', 'http://www.wikidata.org/entity/Q3404587'), ('o', 'FIPRESCI Prize of the Festival de Cannes')]
# [('pr', 'http://www.wikidata.org/prop/direct/P1283'), ('p', 'filmography'), ('or', 'http://www.wikidata.org/entity/Q2455835'), ('o', 'Woody Allen filmography')]
# [('pr', 'http://www.wikidata.org/prop/direct/P800'), ('p', 'notable work'), ('or', 'http://www.wikidata.org/entity/Q971865'), ('o', "What's Up, Tiger Lily?")]
# [('pr', 'http://www.wikidata.org/prop/direct/P166'), ('p', 'award received'), ('or', 'http://www.wikidata.org/entity/Q3822438'), ('o', 'Butaca Awards')]
# [('pr', 'http://www.wikidata.org/prop/direct/P1411'), ('p', 'nominated for'), ('or', 'http://www.wikidata.org/entity/Q103360'), ('o', 'Academy Award for Best Director')]
# [('pr', 'http://www.wikidata.org/prop/direct/P166'), ('p', 'award received'), ('or', 'http://www.wikidata.org/entity/Q103360'), ('o', 'Academy Award for Best Director')]
# 20

# %% [markdown]
# I try to find film as an intersection of the property of two films:

# %%
queryString = """
SELECT DISTINCT ?pr ?p ?or ?o
WHERE {
   # bind something
   wd:Q206124 ?pr ?or . # Check properties in common between Midnight in Paris
   wd:Q971865 ?pr ?or . # and What's Up, Tiger Lily 
   # get the label
   # ?pr sc:name ?p.
   # ?or sc:name ?o.
}
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('pr', 'http://www.wikidata.org/prop/direct/P31'), ('p', 'instance of'), ('or', 'http://www.wikidata.org/entity/Q11424'), ('o', 'film')]
# [('pr', 'http://www.wikidata.org/prop/direct/P364'), ('p', 'original language of film or TV show'), ('or', 'http://www.wikidata.org/entity/Q1860'), ('o', 'English')]
# [('pr', 'http://www.wikidata.org/prop/direct/P437'), ('p', 'distribution format'), ('or', 'http://www.wikidata.org/entity/Q723685'), ('o', 'video on demand')]
# [('pr', 'http://www.wikidata.org/prop/direct/P462'), ('p', 'color'), ('or', 'http://www.wikidata.org/entity/Q22006653'), ('o', 'color')]
# [('pr', 'http://www.wikidata.org/prop/direct/P495'), ('p', 'country of origin'), ('or', 'http://www.wikidata.org/entity/Q30'), ('o', 'United States of America')]
# [('pr', 'http://www.wikidata.org/prop/direct/P57'), ('p', 'director'), ('or', 'http://www.wikidata.org/entity/Q25089'), ('o', 'Woody Allen')]
# [('pr', 'http://www.wikidata.org/prop/direct/P58'), ('p', 'screenwriter'), ('or', 'http://www.wikidata.org/entity/Q25089'), ('o', 'Woody Allen')]
# [('pr', 'http://www.wikidata.org/prop/direct/P750'), ('p', 'distributed by'), ('or', 'http://www.wikidata.org/entity/Q907311'), ('o', 'Netflix')]
# 8

# %% [markdown]
# Final query for this task

# %%
queryString = """
SELECT DISTINCT ?or ?o
WHERE {
   wd:Q206124 wdt:P31 ?or . # Midnight in Paris, instance of, ??
   # get the label
   # ?or sc:name ?o.
}
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('or', 'http://www.wikidata.org/entity/Q11424'), ('o', 'film')]
# 1

# %% [markdown]
# ## Task 2
# Identify the BGP for composer

# %%
queryString = """
SELECT DISTINCT ?pr ?p ?or ?o
WHERE {
   wd:Q206124 ?pr ?or . # Midnight in Paris, ??, ??
   # get the label
   # ?pr sc:name ?p.
   # ?or sc:name ?o.
   FILTER regex(?p, "composer").
}
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('pr', 'http://www.wikidata.org/prop/direct/P86'), ('p', 'composer'), ('or', 'http://www.wikidata.org/entity/Q7608199'), ('o', 'Stephane Wrembel')]
# 1

# %% [markdown]
# The one I found is the IRI for the "composer" property (?film "composer" ?person). Does composer exists even as a role? Let's check.

# %%
queryString = """
SELECT DISTINCT ?or ?o
WHERE {
   # bind something
   wd:Q25089 wdt:P106 ?or .
   # get the label
   # ?or sc:name ?o
}
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('or', 'http://www.wikidata.org/entity/Q10800557'), ('o', 'film actor')]
# [('or', 'http://www.wikidata.org/entity/Q15981151'), ('o', 'jazz musician')]
# [('or', 'http://www.wikidata.org/entity/Q18844224'), ('o', 'science fiction writer')]
# [('or', 'http://www.wikidata.org/entity/Q1930187'), ('o', 'journalist')]
# [('or', 'http://www.wikidata.org/entity/Q214917'), ('o', 'playwright')]
# [('or', 'http://www.wikidata.org/entity/Q245068'), ('o', 'comedian')]
# [('or', 'http://www.wikidata.org/entity/Q2526255'), ('o', 'film director')]
# [('or', 'http://www.wikidata.org/entity/Q28389'), ('o', 'screenwriter')]
# [('or', 'http://www.wikidata.org/entity/Q3282637'), ('o', 'film producer')]
# [('or', 'http://www.wikidata.org/entity/Q36180'), ('o', 'writer')]
# [('or', 'http://www.wikidata.org/entity/Q36834'), ('o', 'composer')]
# [('or', 'http://www.wikidata.org/entity/Q482980'), ('o', 'author')]
# [('or', 'http://www.wikidata.org/entity/Q639669'), ('o', 'musician')]
# [('or', 'http://www.wikidata.org/entity/Q948329'), ('o', 'character actor')]
# [('or', 'http://www.wikidata.org/entity/Q118865'), ('o', 'clarinetist')]
# 15

# %% [markdown]
# Final query for this task

# %%
queryString = """
SELECT DISTINCT ?composerr ?composer
WHERE {
   # bind something
   {
       wd:Q25089 wdt:P106 ?composerr .
       # get the label
       # ?composerr sc:name ?composer.
       FILTER regex(?composer, "composer", "i").
   }UNION{
       wd:Q206124 ?composerr  ?or . # Midnight in Paris, ??, ??
       # get the label
       # ?composerr  sc:name ?composer.
       FILTER regex(?composer, "composer").
   }

}
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('composerr', 'http://www.wikidata.org/entity/Q36834'), ('composer', 'composer')]
# [('composerr', 'http://www.wikidata.org/prop/direct/P86'), ('composer', 'composer')]
# 2

# %% [markdown]
# ## Task 3
# Identify the BGP for film genre

# %%
queryString = """
SELECT DISTINCT ?pr ?p ?or ?o
WHERE {
   wd:Q206124 ?pr ?or . # Midnight in Paris, ??, ??
   # get the label
   # ?pr sc:name ?p.
   # ?or sc:name ?o.
   FILTER regex(?p, "genre").
}
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('pr', 'http://www.wikidata.org/prop/direct/P136'), ('p', 'genre'), ('or', 'http://www.wikidata.org/entity/Q102706436'), ('o', 'magic realist film')]
# [('pr', 'http://www.wikidata.org/prop/direct/P136'), ('p', 'genre'), ('or', 'http://www.wikidata.org/entity/Q157394'), ('o', 'fantasy film')]
# [('pr', 'http://www.wikidata.org/prop/direct/P136'), ('p', 'genre'), ('or', 'http://www.wikidata.org/entity/Q471839'), ('o', 'science fiction film')]
# [('pr', 'http://www.wikidata.org/prop/direct/P136'), ('p', 'genre'), ('or', 'http://www.wikidata.org/entity/Q860626'), ('o', 'romantic comedy')]
# 4

# %% [markdown]
# Final query for this task

# %%
queryString = """
SELECT DISTINCT ?pr ?p
WHERE {
   wd:Q206124 ?pr ?or . # Midnight in Paris, ??, ??
   # get the label
   # ?pr sc:name ?p.
   FILTER regex(?p, "genre").
}
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('pr', 'http://www.wikidata.org/prop/direct/P136'), ('p', 'genre')]
# 1

# %% [markdown]
# ## Task 4
# Find how many films are been released in the United States of America from 2010-01-01 to 2015-31-12 for each film genre available (the result set must be genre IRI, label and #films).

# %% [markdown]
# I did not managed to complete this query. As far as I know, the data requested is not in the database.
#
# While there exists properties as "first published", and "published in" (and actually, there are many synonims), I did not find any kind of quad pattern expressing a concept such as:
# ```sparql
# ?film wdt:releasedIn [
#   wdt:place "usa".
#   wdt:date "releaseDate"
# ]
# ```
#
# Looking for the intersection between the first published date and the published coutry is not enough, because many cases may arise. For example, a film could be first published in 2009 and then released in the USA two years later, and this is not catched by this query.

# %%
queryString = """
SELECT DISTINCT  ?or ?o
WHERE {
   wd:Q206124 wdt:P27 ?or . # Midnight in Paris, nationality, ??
   # get the label
   # ?or sc:name ?o.
}
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# Empty

# %%
queryString = """
SELECT DISTINCT  ?or ?pr ?p
WHERE {
   wd:Q206124 ?pr ?or . # Midnight in Paris, nationality, ??
   # get the label
   MINUS {
       wd:Q206124 ?pr ?or .
       # ?or sc:name ?o.
   }
   
   # ?pr sc:name ?p
}
LIMIT 2000
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('or', 'midnightinparis'), ('pr', 'http://www.wikidata.org/prop/direct/P1237'), ('p', 'Box Office Mojo film ID (former scheme)')]
# [('or', 'm/midnight_in_paris'), ('pr', 'http://www.wikidata.org/prop/direct/P1258'), ('p', 'Rotten Tomatoes ID')]
# [('or', '178300'), ('pr', 'http://www.wikidata.org/prop/direct/P1265'), ('p', 'AlloCiné film ID')]
# [('or', 'topic/Midnight-in-Paris'), ('pr', 'http://www.wikidata.org/prop/direct/P1417'), ('p', 'Encyclopædia Britannica Online ID')]
# [('or', 'Midnight in Paris'), ('pr', 'http://www.wikidata.org/prop/direct/P1476'), ('p', 'title')]
# [('or', 'v515754'), ('pr', 'http://www.wikidata.org/prop/direct/P1562'), ('p', 'AllMovie title ID')]
# [('or', 'movie/midnight-in-paris'), ('pr', 'http://www.wikidata.org/prop/direct/P1712'), ('p', 'Metacritic ID')]
# [('or', 'http://commons.wikimedia.org/wiki/Special:FilePath/Owen%20Wilson%20Woody%20Allen%20Cannes%202011.jpg'), ('pr', 'http://www.wikidata.org/prop/direct/P18'), ('p', 'image')]
# [('or', '73172'), ('pr', 'http://www.wikidata.org/prop/direct/P1804'), ('p', 'DNF film ID')]
# [('or', '70181730'), ('pr', 'http://www.wikidata.org/prop/direct/P1874'), ('p', 'Netflix ID')]
# [('or', '73947'), ('pr', 'http://www.wikidata.org/prop/direct/P1970'), ('p', 'MovieMeter film ID')]
# [('or', '94'), ('pr', 'http://www.wikidata.org/prop/direct/P2047'), ('p', 'duration')]
# [('or', '17000000'), ('pr', 'http://www.wikidata.org/prop/direct/P2130'), ('p', 'cost')]
# [('or', '221226248'), ('pr', 'http://www.wikidata.org/prop/direct/P214'), ('p', 'VIAF ID')]
# [('or', '151100000'), ('pr', 'http://www.wikidata.org/prop/direct/P2142'), ('p', 'box office')]
# [('or', '74572'), ('pr', 'http://www.wikidata.org/prop/direct/P2334'), ('p', 'Swedish Film Database film ID')]
# [('or', '1508328'), ('pr', 'http://www.wikidata.org/prop/direct/P2346'), ('p', 'Elonet movie ID')]
# [('or', 'no2011183651'), ('pr', 'http://www.wikidata.org/prop/direct/P244'), ('p', 'Library of Congress authority ID')]
# [('or', '341568'), ('pr', 'http://www.wikidata.org/prop/direct/P2465'), ('p', 'Allcinema film ID')]
# [('or', '49529'), ('pr', 'http://www.wikidata.org/prop/direct/P2508'), ('p', 'KINENOTE film ID')]
# [('or', 'mv49544'), ('pr', 'http://www.wikidata.org/prop/direct/P2509'), ('p', 'Movie Walker film ID')]
# [('or', '7877'), ('pr', 'http://www.wikidata.org/prop/direct/P2518'), ('p', 'Scope.dk film ID')]
# [('or', '274980'), ('pr', 'http://www.wikidata.org/prop/direct/P2529'), ('p', 'ČSFD film ID')]
# [('or', '504465'), ('pr', 'http://www.wikidata.org/prop/direct/P2603'), ('p', 'Kinopoisk film ID')]
# [('or', '802334'), ('pr', 'http://www.wikidata.org/prop/direct/P2631'), ('p', 'TCM Movie Database film ID')]
# [('or', 'movies/midnight-in-paris'), ('pr', 'http://www.wikidata.org/prop/direct/P2638'), ('p', 'TV.com ID')]
# [('or', '10.5240/6AAA-8B9E-40C6-4539-8700-J'), ('pr', 'http://www.wikidata.org/prop/direct/P2704'), ('p', 'EIDR content ID')]
# [('or', '129803'), ('pr', 'http://www.wikidata.org/prop/direct/P2755'), ('p', 'exploitation visa number')]
# [('or', '240757'), ('pr', 'http://www.wikidata.org/prop/direct/P3077'), ('p', 'Cineplex Germany film ID')]
# [('or', '537830'), ('pr', 'http://www.wikidata.org/prop/direct/P3107'), ('p', 'LdiF ID')]
# [('or', '714574'), ('pr', 'http://www.wikidata.org/prop/direct/P3129'), ('p', 'cine.gr film ID')]
# [('or', '2003920'), ('pr', 'http://www.wikidata.org/prop/direct/P3135'), ('p', 'elCinema film ID')]
# [('or', '208115'), ('pr', 'http://www.wikidata.org/prop/direct/P3138'), ('p', 'OFDb film ID')]
# [('or', 't0027413'), ('pr', 'http://www.wikidata.org/prop/direct/P3141'), ('p', 'EDb film ID')]
# [('or', '1365688'), ('pr', 'http://www.wikidata.org/prop/direct/P3143'), ('p', 'elFilm film ID')]
# [('or', 'tt192220'), ('pr', 'http://www.wikidata.org/prop/direct/P3145'), ('p', 'Sratim ID')]
# [('or', '113208'), ('pr', 'http://www.wikidata.org/prop/direct/P3203'), ('p', 'Ciné-Ressources film ID')]
# [('or', '0000-0002-D005-0000-B-0000-0000-4'), ('pr', 'http://www.wikidata.org/prop/direct/P3212'), ('p', 'ISAN')]
# [('or', '24897'), ('pr', 'http://www.wikidata.org/prop/direct/P3302'), ('p', 'Open Media Database film ID')]
# [('or', '7110'), ('pr', 'http://www.wikidata.org/prop/direct/P3340'), ('p', 'Kvikmyndir film ID')]
# [('or', 'Midnight-in-Paris-2011-movie'), ('pr', 'http://www.wikidata.org/prop/direct/P3417'), ('p', 'Quora topic ID')]
# [('or', 'tt1605783'), ('pr', 'http://www.wikidata.org/prop/direct/P345'), ('p', 'IMDb ID')]
# [('or', '68300'), ('pr', 'http://www.wikidata.org/prop/direct/P3593'), ('p', 'AFI Catalog of Feature Films ID')]
# [('or', '326615'), ('pr', 'http://www.wikidata.org/prop/direct/P3804'), ('p', 'TV Guide show ID (former scheme)')]
# [('or', 'Midnight-in-Paris'), ('pr', 'http://www.wikidata.org/prop/direct/P3808'), ('p', 'The Numbers movie ID')]
# [('or', '19631'), ('pr', 'http://www.wikidata.org/prop/direct/P3844'), ('p', 'Deutsche Synchronkartei film ID')]
# [('or', '4593013'), ('pr', 'http://www.wikidata.org/prop/direct/P3933'), ('p', 'Cinema.de ID')]
# [('or', '96233'), ('pr', 'http://www.wikidata.org/prop/direct/P4276'), ('p', 'Cinémathèque québécoise work identifier')]
# [('or', '4f4b8b8d79351'), ('pr', 'http://www.wikidata.org/prop/direct/P4438'), ('p', 'BFI Films, TV and people ID')]
# [('or', '4319218'), ('pr', 'http://www.wikidata.org/prop/direct/P4529'), ('p', 'Douban film ID')]
# [('or', '2479'), ('pr', 'http://www.wikidata.org/prop/direct/P4632'), ('p', 'Bechdel Test Movie List ID')]
# [('or', '567174'), ('pr', 'http://www.wikidata.org/prop/direct/P480'), ('p', 'FilmAffinity ID')]
# [('or', '59436'), ('pr', 'http://www.wikidata.org/prop/direct/P4947'), ('p', 'TMDb movie ID')]
# [('or', '562509'), ('pr', 'http://www.wikidata.org/prop/direct/P5032'), ('p', 'Filmweb.pl film ID')]
# [('or', 'film1/midnightinparis'), ('pr', 'http://www.wikidata.org/prop/direct/P5099'), ('p', 'Il mondo dei doppiatori ID')]
# [('or', '187810'), ('pr', 'http://www.wikidata.org/prop/direct/P5128'), ('p', 'ICAA film catalogue ID')]
# [('or', 'midnight_in_paris'), ('pr', 'http://www.wikidata.org/prop/direct/P5357'), ('p', 'The Encyclopedia of Science Fiction ID')]
# [('or', '11991415'), ('pr', 'http://www.wikidata.org/prop/direct/P5680'), ('p', 'Hoopla title ID')]
# [('or', '2011-01-01T00:00:00Z'), ('pr', 'http://www.wikidata.org/prop/direct/P577'), ('p', 'publication date')]
# [('or', '2011-08-18T00:00:00Z'), ('pr', 'http://www.wikidata.org/prop/direct/P577'), ('p', 'publication date')]
# [('or', 'midnight-in-paris'), ('pr', 'http://www.wikidata.org/prop/direct/P5786'), ('p', 'Moviepilot.de film ID')]
# [('or', 'midnight-in-paris'), ('pr', 'http://www.wikidata.org/prop/direct/P6127'), ('p', 'Letterboxd film ID')]
# [('or', '4466'), ('pr', 'http://www.wikidata.org/prop/direct/P6145'), ('p', 'Academy Awards Database film ID')]
# [('or', '485597050'), ('pr', 'http://www.wikidata.org/prop/direct/P6398'), ('p', 'iTunes movie ID')]
# [('or', '/m/0bs5vty'), ('pr', 'http://www.wikidata.org/prop/direct/P646'), ('p', 'Freebase ID')]
# [('or', '-NoGpkSTK8k'), ('pr', 'http://www.wikidata.org/prop/direct/P6562'), ('p', 'Google Play Movies & TV ID')]
# [('or', '13736'), ('pr', 'http://www.wikidata.org/prop/direct/P6584'), ('p', 'Scripts.com script ID')]
# [('or', 'Film/MidnightInParis'), ('pr', 'http://www.wikidata.org/prop/direct/P6839'), ('p', 'TV Tropes identifier')]
# [('or', '1MVfdab4b8d16af7f26b03ca1205337720f'), ('pr', 'http://www.wikidata.org/prop/direct/P7970'), ('p', 'FandangoNow ID')]
# [('or', 'http://www.sonyclassics.com/midnightinparis/'), ('pr', 'http://www.wikidata.org/prop/direct/P856'), ('p', 'official website')]
# [('or', '118824'), ('pr', 'http://www.wikidata.org/prop/direct/P905'), ('p', 'PORT film ID')]
# [('or', 'XX5213269'), ('pr', 'http://www.wikidata.org/prop/direct/P950'), ('p', 'Biblioteca Nacional de España ID')]
# [('or', 'umc.cmc.2y8vzdbwligazb3681mvrd76j'), ('pr', 'http://www.wikidata.org/prop/direct/P9586'), ('p', 'Apple TV movie ID')]
# [('or', '6527'), ('pr', 'http://www.wikidata.org/prop/direct/P5311'), ('p', 'Kino-teatr.ua film ID')]
# 74

# %%
queryString = """
SELECT DISTINCT  ?or ?o
WHERE {
   wd:Q25089 wdt:P27 ?or . # Woody Allen, nationality, ??
   # get the label
   # ?or sc:name ?o.
}
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('or', 'http://www.wikidata.org/entity/Q30'), ('o', 'United States of America')]
# 1

# %%
queryString = """
SELECT DISTINCT ?pr ?p
WHERE {
   wd:Q206124 ?pr wd:Q30 . # Midnight in Paris, ??, USA
   # get the label
   # ?pr sc:name ?p.
}
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('pr', 'http://www.wikidata.org/prop/direct/P495'), ('p', 'country of origin')]
# 1

# %%
queryString = """
SELECT DISTINCT ?pr ?p ?or ?o
WHERE {
   wd:Q206124 ?pr ?or . # Midnight in Paris, ??, ??
   # get the label
   # ?pr sc:name ?p.
   # ?or sc:name ?o.
   FILTER regex(?p, "releas").
}
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# Empty

# %%
queryString = """
SELECT DISTINCT ?sr ?s ?pr ?p
WHERE {
   # ?sr wdt:P31 wd:Q11424 .
   # ?sr ?pr wd:Q30 . # a generic film, ??, USA
   # get the label
   # ?sr sc:name ?s.
   # ?pr sc:name ?p.
}
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('sr', 'http://www.wikidata.org/entity/Q1193742'), ('s', 'The Thief of Bagdad'), ('pr', 'http://www.wikidata.org/prop/direct/P162'), ('p', 'producer')]
# [('sr', 'http://www.wikidata.org/entity/Q24901279'), ('s', 'Friended to Death'), ('pr', 'http://www.wikidata.org/prop/direct/P17'), ('p', 'country')]
# [('sr', 'http://www.wikidata.org/entity/Q2251688'), ('s', 'Star Tours'), ('pr', 'http://www.wikidata.org/prop/direct/P17'), ('p', 'country')]
# [('sr', 'http://www.wikidata.org/entity/Q6296468'), ('s', 'To Rob a Thief'), ('pr', 'http://www.wikidata.org/prop/direct/P17'), ('p', 'country')]
# [('sr', 'http://www.wikidata.org/entity/Q75836361'), ('s', 'Let There Be Light'), ('pr', 'http://www.wikidata.org/prop/direct/P17'), ('p', 'country')]
# [('sr', 'http://www.wikidata.org/entity/Q108046141'), ('s', 'Five Years North'), ('pr', 'http://www.wikidata.org/prop/direct/P17'), ('p', 'country')]
# [('sr', 'http://www.wikidata.org/entity/Q7327737'), ('s', 'Richard McGeagh'), ('pr', 'http://www.wikidata.org/prop/direct/P27'), ('p', 'country of citizenship')]
# [('sr', 'http://www.wikidata.org/entity/Q15028216'), ('s', 'Wild Card'), ('pr', 'http://www.wikidata.org/prop/direct/P291'), ('p', 'place of publication')]
# [('sr', 'http://www.wikidata.org/entity/Q55403066'), ('s', 'No Postage Necessary'), ('pr', 'http://www.wikidata.org/prop/direct/P291'), ('p', 'place of publication')]
# [('sr', 'http://www.wikidata.org/entity/Q55402869'), ('s', 'Sharp Edges'), ('pr', 'http://www.wikidata.org/prop/direct/P291'), ('p', 'place of publication')]
# [('sr', 'http://www.wikidata.org/entity/Q59587231'), ('s', 'Rust Never Sleeps'), ('pr', 'http://www.wikidata.org/prop/direct/P291'), ('p', 'place of publication')]
# [('sr', 'http://www.wikidata.org/entity/Q13677566'), ('s', 'Timberjack'), ('pr', 'http://www.wikidata.org/prop/direct/P495'), ('p', 'country of origin')]
# [('sr', 'http://www.wikidata.org/entity/Q15490985'), ('s', 'Jailhouse Heat'), ('pr', 'http://www.wikidata.org/prop/direct/P495'), ('p', 'country of origin')]
# [('sr', 'http://www.wikidata.org/entity/Q15046558'), ('s', 'Life After Beth'), ('pr', 'http://www.wikidata.org/prop/direct/P495'), ('p', 'country of origin')]
# [('sr', 'http://www.wikidata.org/entity/Q15584559'), ('s', 'Salvation Nell'), ('pr', 'http://www.wikidata.org/prop/direct/P495'), ('p', 'country of origin')]
# [('sr', 'http://www.wikidata.org/entity/Q15596853'), ('s', 'Burying the Ex'), ('pr', 'http://www.wikidata.org/prop/direct/P495'), ('p', 'country of origin')]
# [('sr', 'http://www.wikidata.org/entity/Q15728077'), ('s', "We're Only Human"), ('pr', 'http://www.wikidata.org/prop/direct/P495'), ('p', 'country of origin')]
# [('sr', 'http://www.wikidata.org/entity/Q15735966'), ('s', 'Dani Daniels: Dare'), ('pr', 'http://www.wikidata.org/prop/direct/P495'), ('p', 'country of origin')]
# [('sr', 'http://www.wikidata.org/entity/Q98411645'), ('s', 'The Blue Whale'), ('pr', 'http://www.wikidata.org/prop/direct/P291'), ('p', 'place of publication')]
# [('sr', 'http://www.wikidata.org/entity/Q1758112'), ('s', "Ender's Game"), ('pr', 'http://www.wikidata.org/prop/direct/P495'), ('p', 'country of origin')]
# 20

# %%
queryString = """
SELECT DISTINCT ?pr ?p
WHERE {
   # ?sr wdt:P31 wd:Q11424 .
   # ?sr ?pr wd:Q30 . # generic film, ??, USA
   # get the label
   # ?sr sc:name ?s.
   # ?pr sc:name ?p.
}
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('pr', 'http://www.wikidata.org/prop/direct/P162'), ('p', 'producer')]
# [('pr', 'http://www.wikidata.org/prop/direct/P17'), ('p', 'country')]
# [('pr', 'http://www.wikidata.org/prop/direct/P27'), ('p', 'country of citizenship')]
# [('pr', 'http://www.wikidata.org/prop/direct/P291'), ('p', 'place of publication')]
# [('pr', 'http://www.wikidata.org/prop/direct/P495'), ('p', 'country of origin')]
# [('pr', 'http://www.wikidata.org/prop/direct/P840'), ('p', 'narrative location')]
# [('pr', 'http://www.wikidata.org/prop/direct/P750'), ('p', 'distributed by')]
# [('pr', 'http://www.wikidata.org/prop/direct/P915'), ('p', 'filming location')]
# [('pr', 'http://www.wikidata.org/prop/direct/P921'), ('p', 'main subject')]
# [('pr', 'http://www.wikidata.org/prop/direct/P1433'), ('p', 'published in')]
# 10

# %%
queryString = """
SELECT DISTINCT ?pr ?p
WHERE {
   # ?or wdt:P31 wd:Q11424 .
   wd:Q30 ?pr ?or . # USA, ??, a film
   # get the label
   # ?or sc:name ?o.
   # ?pr sc:name ?p.
}
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# Empty

# %%
queryString = """
SELECT DISTINCT ?pr ?p
WHERE {
   # ?sr wdt:P31 wd:Q11424 .
   # ?sr ?pr ?or . # generic film, ??, USA
   # get the label
   # ?sr sc:name ?s.
   # ?pr sc:name ?p.
   FILTER regex(?p, "date").
}
LIMIT 10
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('pr', 'http://www.wikidata.org/prop/direct/P577'), ('p', 'publication date')]
# [('pr', 'http://www.wikidata.org/prop/direct/P1191'), ('p', 'date of first performance')]
# [('pr', 'http://www.wikidata.org/prop/direct/P2754'), ('p', 'production date')]
# [('pr', 'http://www.wikidata.org/prop/direct/P2913'), ('p', 'date depicted')]
# [('pr', 'http://www.wikidata.org/prop/direct/P3893'), ('p', 'public domain date')]
# [('pr', 'http://www.wikidata.org/prop/direct/P1619'), ('p', 'date of official opening')]
# [('pr', 'http://www.wikidata.org/prop/direct/P6949'), ('p', 'announcement date')]
# [('pr', 'http://www.wikidata.org/prop/direct/P3999'), ('p', 'date of official closure')]
# [('pr', 'http://www.wikidata.org/prop/direct/P569'), ('p', 'date of birth')]
# [('pr', 'http://www.wikidata.org/prop/direct/P2960'), ('p', 'archive date')]
# 10

# %%
queryString = """
SELECT DISTINCT ?genrer SAMPLE(?genre)
WHERE {
   # ?filmr wdt:P31 wd:Q11424;  # generic film
       # ?releasedIn wd:Q30; # released in the USA
       # ?releaseDate ?date; # with a publication date
       wdt:P136 ?genrer.   # and a genre
   
   VALUES(?releasedIn){
       (wdt:P17)   # country
       (wdt:P291)  # place of publication
       (wdt:P495)  # country of origin
       (wdt:P1433) # publicated in
   }
   
   VALUES(?releasedDate){
       (wdt:P577)   # publication date
       (wdt:P1191)  # date of first performance
       (wdt:P1619)  # date of official opening
   }
   

   # get the label
   # ?genrer sc:name ?genre.
} GROUP BY ?genrer
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('
]
# [('genrer', 'http://www.wikidata.org/entity/Q471839'), ('callret-1', 'science fiction film')]
# [('genrer', 'http://www.wikidata.org/entity/Q4903281'), ('callret-1', 'biblical genre')]
# [('genrer', 'http://www.wikidata.org/entity/Q2101714'), ('callret-1', 'police film')]
# [('genrer', 'http://www.wikidata.org/entity/Q20442589'), ('callret-1', 'LGBT-related film')]
# [('genrer', 'http://www.wikidata.org/entity/Q66948581'), ('callret-1', 'ghost film')]
# [('genrer', 'http://www.wikidata.org/entity/Q1077883'), ('callret-1', 'biopunk')]
# [('genrer', 'http://www.wikidata.org/entity/Q17013749'), ('callret-1', 'historical film')]
# [('genrer', 'http://www.wikidata.org/entity/Q7362831'), ('callret-1', 'romantic thriller')]
# [('genrer', 'http://www.wikidata.org/entity/Q3634883'), ('callret-1', 'supernatural film')]
# [('genrer', 'http://www.wikidata.org/entity/Q208505'), ('callret-1', 'crime novel')]
# [('genrer', 'http://www.wikidata.org/entity/Q191489'), ('callret-1', 'melodrama')]
# [('genrer', 'http://www.wikidata.org/entity/Q2143665'), ('callret-1', "children's film")]
# [('genrer', 'http://www.wikidata.org/entity/Q200092'), ('callret-1', 'horror film')]
# [('genrer', 'http://www.wikidata.org/entity/Q369747'), ('callret-1', 'war film')]
# [('genrer', 'http://www.wikidata.org/entity/Q33130924'), ('callret-1', 'mafia film')]
# [('genrer', 'http://www.wikidata.org/entity/Q895583'), ('callret-1', 'boxing film')]
# [('genrer', 'http://www.wikidata.org/entity/Q16950433'), ('callret-1', 'comedy thriller')]
# [('genrer', 'http://www.wikidata.org/entity/Q7645884'), ('callret-1', 'surf film')]
# [('genrer', 'http://www.wikidata.org/entity/Q275934'), ('callret-1', 'tokusatsu')]
# [('genrer', 'http://www.wikidata.org/entity/Q5778924'), ('callret-1', 'black comedy film')]
# [('genrer', 'http://www.wikidata.org/entity/Q279060'), ('callret-1', 'robinsonade')]
# [('genrer', 'http://www.wikidata.org/entity/Q1723850'), ('callret-1', 'cannibal film')]
# [('genrer', 'http://www.wikidata.org/entity/Q172980'), ('callret-1', 'Western film')]
# [('genrer', 'http://www.wikidata.org/entity/Q19367312'), ('callret-1', 'crime thriller')]
# [('genrer', 'http://www.wikidata.org/entity/Q102260466'), ('callret-1', 'body horror film')]
# [('genrer', 'http://www.wikidata.org/entity/Q15637301'), ('callret-1', 'fantasy anime and manga')]
# [('genrer', 'http://www.wikidata.org/entity/Q4984974'), ('callret-1', 'buddy cop film')]
# [('genrer', 'http://www.wikidata.org/entity/Q95440291'), ('callret-1', 'fantasy comedy film')]
# [('genrer', 'http://www.wikidata.org/entity/Q2118696'), ('callret-1', 'puppetoon')]
# [('genrer', 'http://www.wikidata.org/entity/Q846544'), ('callret-1', 'disaster film')]
# [('genrer', 'http://www.wikidata.org/entity/Q1117103'), ('callret-1', 'Z movie')]
# [('genrer', 'http://www.wikidata.org/entity/Q6722594'), ('callret-1', 'Euro War')]
# [('genrer', 'http://www.wikidata.org/entity/Q4875794'), ('callret-1', 'beach party film')]
# 100

# %%
queryString = """
SELECT DISTINCT ?filmr ?film ?date
WHERE {
   # ?filmr wdt:P31 wd:Q11424;  # generic film
       # ?releaseDate ?date. # with a publication date
       
    VALUES(?releasedDate){
       (wdt:P577)   # publication date
       (wdt:P1191)  # date of first performance
       (wdt:P1619)  # date of official opening
   }
   
   FILTER (?date > "2010-01-01T00:00:00"^^xsd:dateTime)
   FILTER (?date < "2015-31-12T00:00:00"^^xsd:dateTime)

   # get the label
   # ?genrer sc:name ?film.
}
LIMIT 10
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# Empty

# %%
queryString = """
SELECT DISTINCT ?filmr ?film ?releasedDate ?date
WHERE {
   # ?filmr wdt:P31 wd:Q11424;  # generic film
       # ?releaseDate ?date. # with a publication date
       
    VALUES(?releasedDate){
       (wdt:P577)   # publication date
       (wdt:P1191)  # date of first performance
       (wdt:P1619)  # date of official opening
   }
   
   # get the label
   # ?filmr sc:name ?film.
}
LIMIT 10
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('filmr', 'http://www.wikidata.org/entity/Q8178307'), ('film', '15 Park Avenue'), ('releasedDate', 'http://www.wikidata.org/prop/direct/P577'), ('date', 'http://wikiba.se/ontology#Item')]
# [('filmr', 'http://www.wikidata.org/entity/Q8178307'), ('film', '15 Park Avenue'), ('releasedDate', 'http://www.wikidata.org/prop/direct/P1191'), ('date', 'http://wikiba.se/ontology#Item')]
# [('filmr', 'http://www.wikidata.org/entity/Q8178307'), ('film', '15 Park Avenue'), ('releasedDate', 'http://www.wikidata.org/prop/direct/P1619'), ('date', 'http://wikiba.se/ontology#Item')]
# [('filmr', 'http://www.wikidata.org/entity/Q8197668'), ('film', 'Idiot Love'), ('releasedDate', 'http://www.wikidata.org/prop/direct/P577'), ('date', 'http://wikiba.se/ontology#Item')]
# [('filmr', 'http://www.wikidata.org/entity/Q8197668'), ('film', 'Idiot Love'), ('releasedDate', 'http://www.wikidata.org/prop/direct/P1191'), ('date', 'http://wikiba.se/ontology#Item')]
# [('filmr', 'http://www.wikidata.org/entity/Q8197668'), ('film', 'Idiot Love'), ('releasedDate', 'http://www.wikidata.org/prop/direct/P1619'), ('date', 'http://wikiba.se/ontology#Item')]
# [('filmr', 'http://www.wikidata.org/entity/Q319263'), ('film', 'Doctor in the House'), ('releasedDate', 'http://www.wikidata.org/prop/direct/P577'), ('date', 'http://wikiba.se/ontology#Item')]
# [('filmr', 'http://www.wikidata.org/entity/Q319263'), ('film', 'Doctor in the House'), ('releasedDate', 'http://www.wikidata.org/prop/direct/P1191'), ('date', 'http://wikiba.se/ontology#Item')]
# [('filmr', 'http://www.wikidata.org/entity/Q319263'), ('film', 'Doctor in the House'), ('releasedDate', 'http://www.wikidata.org/prop/direct/P1619'), ('date', 'http://wikiba.se/ontology#Item')]
# [('filmr', 'http://www.wikidata.org/entity/Q8452990'), ('film', "Sunday League - Pepik Hnatek's Final Match"), ('releasedDate', 'http://www.wikidata.org/prop/direct/P577'), ('date', 'http://wikiba.se/ontology#Item')]
# 10

# %%
queryString = """
SELECT DISTINCT ?releasedDate
WHERE {
       
    VALUES(?releasedDate){
       (wdt:P577)   # publication date
       (wdt:P1191)  # date of first performance
       (wdt:P1619)  # date of official opening
   }
}
LIMIT 10
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('releasedDate', 'http://www.wikidata.org/prop/direct/P577')]
# [('releasedDate', 'http://www.wikidata.org/prop/direct/P1191')]
# [('releasedDate', 'http://www.wikidata.org/prop/direct/P1619')]
# 3

# %%
queryString = """
SELECT DISTINCT ?filmr ?film ?releasedDate ?dateObj ?pr ?p ?or ?o
WHERE {
   # ?filmr wdt:P31 wd:Q11424;  # generic film
       # ?releaseDate ?dateObj. # with a publication date
       
       # ?dateObj ?pr ?or.
       
    VALUES(?releasedDate){
       (wdt:P577)   # publication date
       (wdt:P1191)  # date of first performance
       (wdt:P1619)  # date of official opening
   }
   
   # get the label
   # ?filmr sc:name ?film.
   # ?pr sc:name ?p.
   # ?or sc:name ?o.
}
LIMIT 10
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('filmr', 'http://www.wikidata.org/entity/Q8452990'), ('film', "Sunday League - Pepik Hnatek's Final Match"), ('releasedDate', 'http://www.wikidata.org/prop/direct/P577'), ('dateObj', 'http://www.wikidata.org/entity/Q12024203'), ('pr', 'http://www.wikidata.org/prop/direct/P102'), ('p', 'member of political party'), ('or', 'http://www.wikidata.org/entity/Q10728124'), ('o', 'ANO 2011')]
# [('filmr', 'http://www.wikidata.org/entity/Q8452990'), ('film', "Sunday League - Pepik Hnatek's Final Match"), ('releasedDate', 'http://www.wikidata.org/prop/direct/P1191'), ('dateObj', 'http://www.wikidata.org/entity/Q12024203'), ('pr', 'http://www.wikidata.org/prop/direct/P102'), ('p', 'member of political party'), ('or', 'http://www.wikidata.org/entity/Q10728124'), ('o', 'ANO 2011')]
# [('filmr', 'http://www.wikidata.org/entity/Q8452990'), ('film', "Sunday League - Pepik Hnatek's Final Match"), ('releasedDate', 'http://www.wikidata.org/prop/direct/P1619'), ('dateObj', 'http://www.wikidata.org/entity/Q12024203'), ('pr', 'http://www.wikidata.org/prop/direct/P102'), ('p', 'member of political party'), ('or', 'http://www.wikidata.org/entity/Q10728124'), ('o', 'ANO 2011')]
# [('filmr', 'http://www.wikidata.org/entity/Q13637926'), ('film', 'Indra'), ('releasedDate', 'http://www.wikidata.org/prop/direct/P577'), ('dateObj', 'http://www.wikidata.org/entity/Q41798386'), ('pr', 'http://www.wikidata.org/prop/direct/P103'), ('p', 'native language'), ('or', 'http://www.wikidata.org/entity/Q8097'), ('o', 'Telugu')]
# [('filmr', 'http://www.wikidata.org/entity/Q13637926'), ('film', 'Indra'), ('releasedDate', 'http://www.wikidata.org/prop/direct/P1191'), ('dateObj', 'http://www.wikidata.org/entity/Q41798386'), ('pr', 'http://www.wikidata.org/prop/direct/P103'), ('p', 'native language'), ('or', 'http://www.wikidata.org/entity/Q8097'), ('o', 'Telugu')]
# [('filmr', 'http://www.wikidata.org/entity/Q13637926'), ('film', 'Indra'), ('releasedDate', 'http://www.wikidata.org/prop/direct/P1619'), ('dateObj', 'http://www.wikidata.org/entity/Q41798386'), ('pr', 'http://www.wikidata.org/prop/direct/P103'), ('p', 'native language'), ('or', 'http://www.wikidata.org/entity/Q8097'), ('o', 'Telugu')]
# [('filmr', 'http://www.wikidata.org/entity/Q15724178'), ('film', 'Jhili Mili'), ('releasedDate', 'http://www.wikidata.org/prop/direct/P577'), ('dateObj', 'http://www.wikidata.org/entity/Q106602281'), ('pr', 'http://www.wikidata.org/prop/direct/P103'), ('p', 'native language'), ('or', 'http://www.wikidata.org/entity/Q33810'), ('o', 'Odia')]
# [('filmr', 'http://www.wikidata.org/entity/Q15724178'), ('film', 'Jhili Mili'), ('releasedDate', 'http://www.wikidata.org/prop/direct/P1191'), ('dateObj', 'http://www.wikidata.org/entity/Q106602281'), ('pr', 'http://www.wikidata.org/prop/direct/P103'), ('p', 'native language'), ('or', 'http://www.wikidata.org/entity/Q33810'), ('o', 'Odia')]
# [('filmr', 'http://www.wikidata.org/entity/Q15724178'), ('film', 'Jhili Mili'), ('releasedDate', 'http://www.wikidata.org/prop/direct/P1619'), ('dateObj', 'http://www.wikidata.org/entity/Q106602281'), ('pr', 'http://www.wikidata.org/prop/direct/P103'), ('p', 'native language'), ('or', 'http://www.wikidata.org/entity/Q33810'), ('o', 'Odia')]
# [('filmr', 'http://www.wikidata.org/entity/Q15725300'), ('film', 'Sakhi Rahila Ae Singha Duara'), ('releasedDate', 'http://www.wikidata.org/prop/direct/P577'), ('dateObj', 'http://www.wikidata.org/entity/Q10935114'), ('pr', 'http://www.wikidata.org/prop/direct/P103'), ('p', 'native language'), ('or', 'http://www.wikidata.org/entity/Q33810'), ('o', 'Odia')]
# 10

# %%
queryString = """
SELECT DISTINCT ?dateObj ?pr ?p ?or ?o
WHERE {
   wd:Q8452990 wdt:P31 wd:Q11424;  # generic film
       wdt:P577 ?dateObj. # with a publication date
       
       # ?dateObj ?pr ?or.
       
   # get the label
   # ?pr sc:name ?p.
   # ?or sc:name ?o.
}
LIMIT 10
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# Empty

# %%
queryString = """
SELECT DISTINCT ?dateObj ?pr ?p ?or ?o
WHERE {
   wd:Q206124 wdt:P31 wd:Q11424;  # generic film
       wdt:P577 ?dateObj. # with a publication date
       
       # ?dateObj ?pr ?or.
       
   # get the label
   # ?pr sc:name ?p.
   # ?or sc:name ?o.
}
LIMIT 10
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# Empty

# %%
queryString = """
SELECT DISTINCT ?dateObj
WHERE {
    
   wd:Q206124 wdt:P577 ?dateObj. # with a publication date
        FILTER (?dateObj > "2010-01-01T00:00:00Z"^^xsd:dateTime)
        FILTER (?dateObj < "2020-01-01T00:00:00Z"^^xsd:dateTime) .
}
LIMIT 10
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# Empty

# %%
queryString = """
SELECT DISTINCT ?filmr ?film ?dateObj
WHERE {
    # ?filmr wdt:P31 wd:Q11424.
    # ?filmr wdt:P577 ?dateObj. # with a publication date
        FILTER (?dateObj > "2010-01-01T00:00:00Z"^^xsd:dateTime)
        FILTER (?dateObj < "2020-01-01T00:00:00Z"^^xsd:dateTime) .
       
    # ?filmr sc:name ?film
}
LIMIT 10
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('filmr', 'http://www.wikidata.org/entity/Q8452990'), ('film', "Sunday League - Pepik Hnatek's Final Match"), ('dateObj', '2012-03-29T00:00:00Z')]
# [('filmr', 'http://www.wikidata.org/entity/Q284184'), ('film', 'Ra.One'), ('dateObj', '2011-01-01T00:00:00Z')]
# [('filmr', 'http://www.wikidata.org/entity/Q284184'), ('film', 'Ra.One'), ('dateObj', '2011-10-26T00:00:00Z')]
# [('filmr', 'http://www.wikidata.org/entity/Q13693967'), ('film', 'Cross'), ('dateObj', '2012-10-04T00:00:00Z')]
# [('filmr', 'http://www.wikidata.org/entity/Q15464247'), ('film', 'What the Fish'), ('dateObj', '2013-01-01T00:00:00Z')]
# [('filmr', 'http://www.wikidata.org/entity/Q15475237'), ('film', 'Mediastan'), ('dateObj', '2013-10-02T00:00:00Z')]
# [('filmr', 'http://www.wikidata.org/entity/Q15490985'), ('film', 'Jailhouse Heat'), ('dateObj', '2011-01-01T00:00:00Z')]
# [('filmr', 'http://www.wikidata.org/entity/Q15046558'), ('film', 'Life After Beth'), ('dateObj', '2014-01-01T00:00:00Z')]
# [('filmr', 'http://www.wikidata.org/entity/Q15596853'), ('film', 'Burying the Ex'), ('dateObj', '2014-01-01T00:00:00Z')]
# [('filmr', 'http://www.wikidata.org/entity/Q13732569'), ('film', 'Move On'), ('dateObj', '2012-01-01T00:00:00Z')]
# 10

# %%
queryString = """
SELECT DISTINCT ?filmr ?film ?dateObj
WHERE {
    # ?filmr wdt:P31 wd:Q11424.
    
    # ?filmr (wdt:P291|wdt:P17|wdt:P495|wdt:P1433)  wd:Q30.  # country

    
    # ?filmr (wdt:P577|wdt:P1191|wdt:P1619) ?dateObj. # with a publication date
        FILTER (?dateObj > "2010-01-01T00:00:00Z"^^xsd:dateTime)
        FILTER (?dateObj < "2020-01-01T00:00:00Z"^^xsd:dateTime) .
       
    # ?filmr sc:name ?film
}
LIMIT 10
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('filmr', 'http://www.wikidata.org/entity/Q24901279'), ('film', 'Friended to Death'), ('dateObj', '2014-05-02T00:00:00Z')]
# [('filmr', 'http://www.wikidata.org/entity/Q75836361'), ('film', 'Let There Be Light'), ('dateObj', '2017-01-01T00:00:00Z')]
# [('filmr', 'http://www.wikidata.org/entity/Q15028216'), ('film', 'Wild Card'), ('dateObj', '2015-01-01T00:00:00Z')]
# [('filmr', 'http://www.wikidata.org/entity/Q15028216'), ('film', 'Wild Card'), ('dateObj', '2015-01-29T00:00:00Z')]
# [('filmr', 'http://www.wikidata.org/entity/Q15028216'), ('film', 'Wild Card'), ('dateObj', '2015-02-12T00:00:00Z')]
# [('filmr', 'http://www.wikidata.org/entity/Q55403066'), ('film', 'No Postage Necessary'), ('dateObj', '2018-07-06T00:00:00Z')]
# [('filmr', 'http://www.wikidata.org/entity/Q55402869'), ('film', 'Sharp Edges'), ('dateObj', '2018-07-06T00:00:00Z')]
# [('filmr', 'http://www.wikidata.org/entity/Q15490985'), ('film', 'Jailhouse Heat'), ('dateObj', '2011-01-01T00:00:00Z')]
# [('filmr', 'http://www.wikidata.org/entity/Q15046558'), ('film', 'Life After Beth'), ('dateObj', '2014-01-01T00:00:00Z')]
# [('filmr', 'http://www.wikidata.org/entity/Q15596853'), ('film', 'Burying the Ex'), ('dateObj', '2014-01-01T00:00:00Z')]
# 10

# %%
queryString = """
SELECT DISTINCT ?filmr ?film ?or ?pr
WHERE {
    # ?filmr wdt:P31 wd:Q11424.
    

    
    # ?filmr (wdt:P577|wdt:P1191|wdt:P1619) [?pr ?or]. # with a publication date

   # get the label
   # ?filmr sc:name ?film.

}
LIMIT 10
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# Empty

# %%
queryString = """
SELECT DISTINCT ?filmr ?film ?o ?p
WHERE {
    # ?filmr wdt:P31 wd:Q11424.
    
    BIND(str(?or) as ?o)
    BIND(str(?pr) as ?p)

    
    # ?filmr (wdt:P577|wdt:P1191|wdt:P1619) [?pr ?or]. # with a publication date

   # get the label
   # ?filmr sc:name ?film.

}
LIMIT 10
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# Empty

# %%
queryString = """
SELECT DISTINCT ?filmr ?res
WHERE {
    # ?filmr wdt:P291 ?res.

}
LIMIT 10
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('filmr', 'http://www.wikidata.org/entity/Q11945446'), ('res', 'http://www.wikidata.org/entity/Q13933')]
# [('filmr', 'http://www.wikidata.org/entity/Q100288782'), ('res', 'http://www.wikidata.org/entity/Q1073686')]
# [('filmr', 'http://www.wikidata.org/entity/Q55671290'), ('res', 'http://www.wikidata.org/entity/Q1073686')]
# [('filmr', 'http://www.wikidata.org/entity/Q76824204'), ('res', 'http://www.wikidata.org/entity/Q1627591')]
# [('filmr', 'http://www.wikidata.org/entity/Q55666016'), ('res', 'http://www.wikidata.org/entity/Q2156427')]
# [('filmr', 'http://www.wikidata.org/entity/Q55671120'), ('res', 'http://www.wikidata.org/entity/Q982554')]
# [('filmr', 'http://www.wikidata.org/entity/Q56237018'), ('res', 'http://www.wikidata.org/entity/Q1376400')]
# [('filmr', 'http://www.wikidata.org/entity/Q55666605'), ('res', 'http://www.wikidata.org/entity/Q2299339')]
# [('filmr', 'http://www.wikidata.org/entity/Q19750830'), ('res', 'http://www.wikidata.org/entity/Q2562317')]
# [('filmr', 'http://www.wikidata.org/entity/Q55667259'), ('res', 'http://www.wikidata.org/entity/Q3241389')]
# 10

# %%
queryString = """
SELECT DISTINCT ?filmr ?res
WHERE {
    # ?filmr wdt:P291 wd:Q30.

}
LIMIT 10
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('filmr', 'http://www.wikidata.org/entity/Q25411938')]
# [('filmr', 'http://www.wikidata.org/entity/Q3186989')]
# [('filmr', 'http://www.wikidata.org/entity/Q15753706')]
# [('filmr', 'http://www.wikidata.org/entity/Q2746500')]
# [('filmr', 'http://www.wikidata.org/entity/Q2915291')]
# [('filmr', 'http://www.wikidata.org/entity/Q1101326')]
# [('filmr', 'http://www.wikidata.org/entity/Q17002288')]
# [('filmr', 'http://www.wikidata.org/entity/Q17008085')]
# [('filmr', 'http://www.wikidata.org/entity/Q17012904')]
# [('filmr', 'http://www.wikidata.org/entity/Q17016033')]
# 10

# %%
queryString = """
SELECT DISTINCT ?filmr ?res
WHERE {
    # ?filmr  wdt:P31 wd:Q11424.
    # ?filmr wdt:P291 wd:Q30.

}
LIMIT 10
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('filmr', 'http://www.wikidata.org/entity/Q15028216')]
# [('filmr', 'http://www.wikidata.org/entity/Q55403066')]
# [('filmr', 'http://www.wikidata.org/entity/Q55402869')]
# [('filmr', 'http://www.wikidata.org/entity/Q59587231')]
# [('filmr', 'http://www.wikidata.org/entity/Q98411645')]
# 5

# %%
queryString = """
SELECT DISTINCT ?filmr ?s
WHERE {
    # ?filmr  wdt:P31 wd:Q11424.
    # ?filmr ?s [wdt:P291 wd:Q30].

}
LIMIT 10
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('filmr', 'http://www.wikidata.org/entity/Q1758112'), ('s', 'http://www.wikidata.org/prop/direct/P144')]
# [('filmr', 'http://www.wikidata.org/entity/Q160560'), ('s', 'http://www.wikidata.org/prop/direct/P138')]
# [('filmr', 'http://www.wikidata.org/entity/Q160560'), ('s', 'http://www.wikidata.org/prop/direct/P144')]
# [('filmr', 'http://www.wikidata.org/entity/Q300547'), ('s', 'http://www.wikidata.org/prop/direct/P144')]
# [('filmr', 'http://www.wikidata.org/entity/Q300624'), ('s', 'http://www.wikidata.org/prop/direct/P156')]
# [('filmr', 'http://www.wikidata.org/entity/Q2132944'), ('s', 'http://www.wikidata.org/prop/direct/P1889')]
# [('filmr', 'http://www.wikidata.org/entity/Q152456'), ('s', 'http://www.wikidata.org/prop/direct/P144')]
# [('filmr', 'http://www.wikidata.org/entity/Q18547944'), ('s', 'http://www.wikidata.org/prop/direct/P144')]
# [('filmr', 'http://www.wikidata.org/entity/Q195274'), ('s', 'http://www.wikidata.org/prop/direct/P144')]
# [('filmr', 'http://www.wikidata.org/entity/Q163038'), ('s', 'http://www.wikidata.org/prop/direct/P144')]
# 10

# %%
queryString = """
SELECT DISTINCT  ?s
WHERE {
    # ?filmr  wdt:P31 wd:Q11424.
    # ?filmr ?s [wdt:P291 wd:Q30].

}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('s', 'http://www.wikidata.org/prop/direct/P144')]
# [('s', 'http://www.wikidata.org/prop/direct/P138')]
# [('s', 'http://www.wikidata.org/prop/direct/P156')]
# [('s', 'http://www.wikidata.org/prop/direct/P1889')]
# [('s', 'http://www.wikidata.org/prop/direct/P155')]
# [('s', 'http://www.wikidata.org/prop/direct/P921')]
# [('s', 'http://www.wikidata.org/prop/direct/P406')]
# [('s', 'http://www.wikidata.org/prop/direct/P272')]
# 8

# %%
queryString = """
SELECT DISTINCT  ?s ?sl
WHERE {
    # ?filmr  wdt:P31 wd:Q11424.
    # ?filmr ?s [wdt:P291 wd:Q30].

    # ?s sc:name ?sl
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('s', 'http://www.wikidata.org/prop/direct/P138'), ('sl', 'named after')]
# [('s', 'http://www.wikidata.org/prop/direct/P144'), ('sl', 'based on')]
# [('s', 'http://www.wikidata.org/prop/direct/P155'), ('sl', 'follows')]
# [('s', 'http://www.wikidata.org/prop/direct/P156'), ('sl', 'followed by')]
# [('s', 'http://www.wikidata.org/prop/direct/P1889'), ('sl', 'different from')]
# [('s', 'http://www.wikidata.org/prop/direct/P921'), ('sl', 'main subject')]
# [('s', 'http://www.wikidata.org/prop/direct/P406'), ('sl', 'soundtrack release')]
# [('s', 'http://www.wikidata.org/prop/direct/P272'), ('sl', 'production company')]
# 8

# %% [markdown]
# Final query for this task

# %%
queryString = """
SELECT DISTINCT ?genrer (SAMPLE(?genre) as ?genreLabel) (COUNT(distinct ?filmr) as ?filmCount)
WHERE {

    # ?filmr wdt:P31 wd:Q11424.  # generic film
    
    # ?filmr wdt:P136 ?genrer.   # with genre
    
    # ?filmr (wdt:P291|wdt:P17|wdt:P495|wdt:P1433)  wd:Q30.  # country = USA

    
    # ?filmr (wdt:P577|wdt:P1191|wdt:P1619) ?dateObj. # with a publication date
        FILTER (?dateObj > "2010-01-01T00:00:00Z"^^xsd:dateTime)
        FILTER (?dateObj < "2020-01-01T00:00:00Z"^^xsd:dateTime) .
       
   # get the label
   # ?genrer sc:name ?genre.
} GROUP BY ?genrer
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# The operation failed EndPointInternalError: endpoint returned code 500 and response.
#
# Response:
# b'Virtuoso 42000 Error The estimated execution time 26992 (sec) exceeds the limit of 800 (sec).\n\nSPARQL query:\n\n##-f457feb412-##\nPREFIX wd: <http://www.wikidata.org/entity/> \nPREFIX wdt: <http://www.wikidata.org/prop/direct/> \nPREFIX sc: <http://schema.org/>\n\n\nSELECT DISTINCT ?genrer (SAMPLE(?genre) as ?genreLabel) (COUNT(distinct ?filmr) as ?filmCount)\nWHERE {\n\n    ?filmr wdt:P31 wd:Q11424.  # generic film\n    \n    ?filmr wdt:P136 ?genrer.   # with genre\n    \n    ?filmr (wdt:P291|wdt:P17|wdt:P495|wdt:P1433)  wd:Q30.  # country = USA\n\n    \n    ?filmr (wdt:P577|wdt:P1191|wdt:P1619) ?dateObj. # with a publication date\n        FILTER (?dateObj > "2010-01-01T00:00:00Z"^^xsd:dateTime)\n        FILTER (?dateObj < "2020-01-01T00:00:00Z"^^xsd:dateTime) .\n       \n   # get the label\n   ?genrer sc:name ?genre.\n} GROUP BY ?genrer\nLIMIT 100\n'

# %%
queryString = """
SELECT DISTINCT ?filmr ?film
WHERE {
    # ?filmr wdt:P31 wd:Q11424.
    
    # ?filmr (wdt:P291|wdt:P17|wdt:P495|wdt:P1433)  wd:Q30.  # country

    
    # ?filmr (wdt:P577|wdt:P1191|wdt:P1619) ?dateObj. # with a publication date
        FILTER (?dateObj > "2010-01-01T00:00:00Z"^^xsd:dateTime)
        FILTER (?dateObj < "2015-12-31T00:00:00Z"^^xsd:dateTime) .
       
    # ?filmr sc:name ?film
}
LIMIT 100"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('filmr', 'http://www.wikidata.org/entity/Q24901279'), ('film', 'Friended to Death')]
# [('filmr', 'http://www.wikidata.org/entity/Q15028216'), ('film', 'Wild Card')]
# [('filmr', 'http://www.wikidata.org/entity/Q15490985'), ('film', 'Jailhouse Heat')]
# [('filmr', 'http://www.wikidata.org/entity/Q15046558'), ('film', 'Life After Beth')]
# [('filmr', 'http://www.wikidata.org/entity/Q15596853'), ('film', 'Burying the Ex')]
# [('filmr', 'http://www.wikidata.org/entity/Q1187607'), ('film', 'Edge of Tomorrow')]
# [('filmr', 'http://www.wikidata.org/entity/Q18225084'), ('film', 'The Hateful Eight')]
# [('filmr', 'http://www.wikidata.org/entity/Q26833665'), ('film', '(Dis)Honesty: The Truth About Lies')]
# [('filmr', 'http://www.wikidata.org/entity/Q26833709'), ('film', 'News from Nowhere')]
# [('filmr', 'http://www.wikidata.org/entity/Q263930'), ('film', 'The Next Three Days')]
# [('filmr', 'http://www.wikidata.org/entity/Q3522995'), ('film', 'Third Person')]
# [('filmr', 'http://www.wikidata.org/entity/Q30126698'), ('film', 'CobraGator')]
# [('filmr', 'http://www.wikidata.org/entity/Q30126705'), ('film', 'Shark Babes')]
# [('filmr', 'http://www.wikidata.org/entity/Q33256144'), ('film', 'Fire Twister')]
# [('filmr', 'http://www.wikidata.org/entity/Q15140437'), ('film', 'Terminator Genisys')]
# [('filmr', 'http://www.wikidata.org/entity/Q3512046'), ('film', 'Jurassic World')]
# [('filmr', 'http://www.wikidata.org/entity/Q492089'), ('film', 'The Adjustment Bureau')]
# [('filmr', 'http://www.wikidata.org/entity/Q553920'), ('film', 'Red Dawn')]
# [('filmr', 'http://www.wikidata.org/entity/Q5887360'), ('film', 'Guardians of the Galaxy')]
# [('filmr', 'http://www.wikidata.org/entity/Q1954593'), ('film', 'The Collection')]
# [('filmr', 'http://www.wikidata.org/entity/Q4985891'), ('film', 'X-Men: Days of Future Past')]
# [('filmr', 'http://www.wikidata.org/entity/Q604876'), ('film', 'Alex Cross')]
# [('filmr', 'http://www.wikidata.org/entity/Q604889'), ('film', 'Bachelorette')]
# [('filmr', 'http://www.wikidata.org/entity/Q3020730'), ('film', 'Death Race 3: Inferno')]
# [('filmr', 'http://www.wikidata.org/entity/Q1763181'), ('film', 'A Good Old Fashioned Orgy')]
# [('filmr', 'http://www.wikidata.org/entity/Q1764045'), ('film', 'Spooky Buddies')]
# [('filmr', 'http://www.wikidata.org/entity/Q1840670'), ('film', 'Side by Side')]
# [('filmr', 'http://www.wikidata.org/entity/Q1862218'), ('film', 'Cedar Rapids')]
# [('filmr', 'http://www.wikidata.org/entity/Q18602670'), ('film', 'Spectre')]
# [('filmr', 'http://www.wikidata.org/entity/Q2767704'), ('film', "Free Willy: Escape from Pirate's Cove")]
# [('filmr', 'http://www.wikidata.org/entity/Q2778386'), ('film', '2 Days in New York')]
# [('filmr', 'http://www.wikidata.org/entity/Q3346204'), ('film', 'Beneath the Darkness')]
# [('filmr', 'http://www.wikidata.org/entity/Q3349019'), ('film', 'Oculus')]
# [('filmr', 'http://www.wikidata.org/entity/Q5087306'), ('film', 'Chasing Eagle Rock')]
# [('filmr', 'http://www.wikidata.org/entity/Q13374569'), ('film', 'Need for Speed')]
# 100

# %%
queryString = """
SELECT DISTINCT ?genrer SAMPLE(?genre) (COUNT(distinct ?filmr) AS ?filmCount)
WHERE {
   # ?filmr wdt:P31 wd:Q11424;  # generic film
       # ?releasedIn wd:Q30; # released in the USA
       # ?releaseDate ?date; # with a publication date
       wdt:P136 ?genrer.   # and a genre
   
   VALUES(?releasedIn){
       (wdt:P17)   # country
       (wdt:P291)  # place of publication
       (wdt:P495)  # country of origin
       (wdt:P1433) # publicated in
   }
   
   VALUES(?releasedDate){
       (wdt:P577)   # publication date
       (wdt:P1191)  # date of first performance
       (wdt:P1619)  # date of official opening
   }
   
    FILTER (?date > "2010-01-01T00:00:00Z"^^xsd:dateTime)
    FILTER (?date < "2015-12-31T00:00:00Z"^^xsd:dateTime) .
       

   

   # get the label
   # ?genrer sc:name ?genre.
} GROUP BY ?genrer ORDER BY DESC (?filmCount)
LIMIT 500
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('genrer', 'http://www.wikidata.org/entity/Q130232'), ('callret-1', 'drama'), ('filmCount', '1433')]
# [('genrer', 'http://www.wikidata.org/entity/Q93204'), ('callret-1', 'documentary film'), ('filmCount', '1029')]
# [('genrer', 'http://www.wikidata.org/entity/Q200092'), ('callret-1', 'horror film'), ('filmCount', '612')]
# [('genrer', 'http://www.wikidata.org/entity/Q157443'), ('callret-1', 'comedy film'), ('filmCount', '612')]
# [('genrer', 'http://www.wikidata.org/entity/Q188473'), ('callret-1', 'action film'), ('filmCount', '523')]
# [('genrer', 'http://www.wikidata.org/entity/Q2484376'), ('callret-1', 'thriller film'), ('filmCount', '469')]
# [('genrer', 'http://www.wikidata.org/entity/Q471839'), ('callret-1', 'science fiction film'), ('filmCount', '294')]
# [('genrer', 'http://www.wikidata.org/entity/Q20442589'), ('callret-1', 'LGBT-related film'), ('filmCount', '283')]
# [('genrer', 'http://www.wikidata.org/entity/Q859369'), ('callret-1', 'comedy-drama'), ('filmCount', '272')]
# [('genrer', 'http://www.wikidata.org/entity/Q959790'), ('callret-1', 'crime film'), ('filmCount', '260')]
# [('genrer', 'http://www.wikidata.org/entity/Q860626'), ('callret-1', 'romantic comedy'), ('filmCount', '229')]
# [('genrer', 'http://www.wikidata.org/entity/Q1054574'), ('callret-1', 'romance film'), ('filmCount', '195')]
# [('genrer', 'http://www.wikidata.org/entity/Q645928'), ('callret-1', 'biographical film'), ('filmCount', '191')]
# [('genrer', 'http://www.wikidata.org/entity/Q157394'), ('callret-1', 'fantasy film'), ('filmCount', '185')]
# [('genrer', 'http://www.wikidata.org/entity/Q52207399'), ('callret-1', 'film based on a novel'), ('filmCount', '158')]
# [('genrer', 'http://www.wikidata.org/entity/Q185529'), ('callret-1', 'pornographic film'), ('filmCount', '133')]
# [('genrer', 'http://www.wikidata.org/entity/Q319221'), ('callret-1', 'adventure film'), ('filmCount', '133')]
# [('genrer', 'http://www.wikidata.org/entity/Q1200678'), ('callret-1', 'mystery film'), ('filmCount', '131')]
# [('genrer', 'http://www.wikidata.org/entity/Q224700'), ('callret-1', 'comedy horror'), ('filmCount', '118')]
# [('genrer', 'http://www.wikidata.org/entity/Q459290'), ('callret-1', 'independent film'), ('filmCount', '100')]
# [('genrer', 'http://www.wikidata.org/entity/Q842256'), ('callret-1', 'musical film'), ('filmCount', '93')]
# [('genrer', 'http://www.wikidata.org/entity/Q1146335'), ('callret-1', 'teen film'), ('filmCount', '80')]
# [('genrer', 'http://www.wikidata.org/entity/Q853630'), ('callret-1', 'slasher film'), ('filmCount', '77')]
# [('genrer', 'http://www.wikidata.org/entity/Q369747'), ('callret-1', 'war film'), ('filmCount', '73')]
# [('genrer', 'http://www.wikidata.org/entity/Q2975633'), ('callret-1', 'coming-of-age story'), ('filmCount', '72')]
# [('genrer', 'http://www.wikidata.org/entity/Q3272147'), ('callret-1', 'found footage'), ('filmCount', '70')]
# [('genrer', 'http://www.wikidata.org/entity/Q28026639'), ('callret-1', 'Christmas film'), ('filmCount', '67')]
# [('genrer', 'http://www.wikidata.org/entity/Q52162262'), ('callret-1', 'film based on literature'), ('filmCount', '61')]
# [('genrer', 'http://www.wikidata.org/entity/Q3072049'), ('callret-1', 'zombie film'), ('filmCount', '60')]
# [('genrer', 'http://www.wikidata.org/entity/Q622548'), ('callret-1', 'parody film'), ('filmCount', '57')]
# [('genrer', 'http://www.wikidata.org/entity/Q20443008'), ('callret-1', 'dystopian film'), ('filmCount', '57')]
# [('genrer', 'http://www.wikidata.org/entity/Q2143665'), ('callret-1', "children's film"), ('filmCount', '56')]
# [('genrer', 'http://www.wikidata.org/entity/Q1535153'), ('callret-1', 'superhero film'), ('filmCount', '53')]
# [('genrer', 'http://www.wikidata.org/entity/Q16254232'), ('callret-1', 'porn parody'), ('filmCount', '50')]
# [('genrer', 'http://www.wikidata.org/entity/Q2137852'), ('callret-1', 'vampire film'), ('filmCount', '48')]
# [('genrer', 'http://www.wikidata.org/entity/Q1341051'), ('callret-1', 'post-apocalyptic film'), ('filmCount', '46')]
# [('genrer', 'http://www.wikidata.org/entity/Q19367312'), ('callret-1', 'crime thriller'), ('filmCount', '42')]
# [('genrer', 'http://www.wikidata.org/entity/Q663106'), ('callret-1', 'buddy film'), ('filmCount', '38')]
# [('genrer', 'http://www.wikidata.org/entity/Q1339864'), ('callret-1', 'sport film'), ('filmCount', '37')]
# [('genrer', 'http://www.wikidata.org/entity/Q846544'), ('callret-1', 'disaster film'), ('filmCount', '34')]
# [('genrer', 'http://www.wikidata.org/entity/Q52
), ('filmCount', '1')]
# [('genrer', 'http://www.wikidata.org/entity/Q2991560'), ('callret-1', 'sex comedy'), ('filmCount', '1')]
# [('genrer', 'http://www.wikidata.org/entity/Q9168'), ('callret-1', 'Persian'), ('filmCount', '1')]
# [('genrer', 'http://www.wikidata.org/entity/Q542475'), ('callret-1', 'costume drama'), ('filmCount', '1')]
# [('genrer', 'http://www.wikidata.org/entity/Q904447'), ('callret-1', 'Military science fiction'), ('filmCount', '1')]
# [('genrer', 'http://www.wikidata.org/entity/Q174526'), ('callret-1', 'cyberpunk'), ('filmCount', '1')]
# [('genrer', 'http://www.wikidata.org/entity/Q1957385'), ('callret-1', 'cinematic fairy tale'), ('filmCount', '1')]
# [('genrer', 'http://www.wikidata.org/entity/Q197949'), ('callret-1', 'post-apocalyptic fiction'), ('filmCount', '1')]
# [('genrer', 'http://www.wikidata.org/entity/Q25372'), ('callret-1', 'drama'), ('filmCount', '1')]
# [('genrer', 'http://www.wikidata.org/entity/Q7210294'), ('callret-1', 'political drama'), ('filmCount', '1')]
# [('genrer', 'http://www.wikidata.org/entity/Q6457531'), ('callret-1', 'LDS cinema'), ('filmCount', '1')]
# [('genrer', 'http://www.wikidata.org/entity/Q1760610'), ('callret-1', 'comic book'), ('filmCount', '1')]
# [('genrer', 'http://www.wikidata.org/entity/Q131539'), ('callret-1', "children's literature"), ('filmCount', '1')]
# [('genrer', 'http://www.wikidata.org/entity/Q9326077'), ('callret-1', 'speculative fiction'), ('filmCount', '1')]
# [('genrer', 'http://www.wikidata.org/entity/Q181001'), ('callret-1', 'erotica'), ('filmCount', '1')]
# [('genrer', 'http://www.wikidata.org/entity/Q677466'), ('callret-1', 'video clip'), ('filmCount', '1')]
# [('genrer', 'http://www.wikidata.org/entity/Q131272'), ('callret-1', 'soul music'), ('filmCount', '1')]
# [('genrer', 'http://www.wikidata.org/entity/Q222639'), ('callret-1', 'swashbuckler film'), ('filmCount', '1')]
# [('genrer', 'http://www.wikidata.org/entity/Q2561438'), ('callret-1', 'slice of life'), ('filmCount', '1')]
# [('genrer', 'http://www.wikidata.org/entity/Q1259759'), ('callret-1', 'miniseries'), ('filmCount', '1')]
# [('genrer', 'http://www.wikidata.org/entity/Q28968258'), ('callret-1', 'computer-animated film'), ('filmCount', '1')]
# [('genrer', 'http://www.wikidata.org/entity/Q6729489'), ('callret-1', 'mafia comedy film'), ('filmCount', '1')]
# [('genrer', 'http://www.wikidata.org/entity/Q47009776'), ('callret-1', 'apocalyptic film'), ('filmCount', '1')]
# [('genrer', 'http://www.wikidata.org/entity/Q66425231'), ('callret-1', 'Redsploitation'), ('filmCount', '1')]
# [('genrer', 'http://www.wikidata.org/entity/Q1777448'), ('callret-1', 'hardcore pornography'), ('filmCount', '1')]
# [('genrer', 'http://www.wikidata.org/entity/Q472637'), ('callret-1', 'docufiction'), ('filmCount', '1')]
# [('genrer', 'http://www.wikidata.org/entity/Q25110269'), ('callret-1', 'live-action/animated film'), ('filmCount', '1')]
# [('genrer', 'http://www.wikidata.org/entity/Q1097273'), ('callret-1', 'epic literature'), ('filmCount', '1')]
# [('genrer', 'http://www.wikidata.org/entity/Q103888910'), ('callret-1', 'intersex film'), ('filmCount', '1')]
# [('genrer', 'http://www.wikidata.org/entity/Q2724311'), ('callret-1', 'New Queer Cinema'), ('filmCount', '1')]
# [('genrer', 'http://www.wikidata.org/entity/Q18089587'), ('callret-1', 'stop-motion animated film'), ('filmCount', '1')]
# [('genrer', 'http://www.wikidata.org/entity/Q332564'), ('callret-1', 'abstract film'), ('filmCount', '1')]
# 195

# %% [markdown]
# ## Task 5
# Consider the timespan from 2001-01-01 to nowadays. Find the number of films released in this timespan divided by film genre and return only those with more than 50 films released every year (the result set must be genre IRI and label).

# %% [markdown]
# At first, I would like to be sure I'm able to handle the NOW() function in the right way:

# %%
queryString = """
SELECT DISTINCT ?now
WHERE {
   BIND(NOW() as ?now)
}
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('now', '2022-12-20T23:24:50.117375')]
# 1

# %%
queryString = """
SELECT DISTINCT ?year
WHERE {

   BIND(NOW() as ?now)
   VALUES(?year){
       ("1970-01-01T00:00:00"^^xsd:dateTime)
       ("1979-01-01T00:00:00"^^xsd:dateTime)
       ("2023-01-01T00:00:00"^^xsd:dateTime)
   }
   
     FILTER (?now > ?year)

}
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('year', '1970-01-01T00:00:00')]
# [('year', '1979-01-01T00:00:00')]
# 2

# %%
queryString = """
SELECT DISTINCT ?genrer SAMPLE(?genre) SAMPLE(?year)
WHERE {

   # ?filmr wdt:P31 wd:Q11424;  # generic film
       # ?releaseDate ?date; # with a publication date
       wdt:P136 ?genrer.   # and a genre
   
   
   VALUES(?releasedDate){
       (wdt:P577)   # publication date
       (wdt:P1191)  # date of first performance
       (wdt:P1619)  # date of official opening
   }
   
      BIND(NOW() as ?now)

    FILTER (?date > "2001-01-01T00:00:00Z"^^xsd:dateTime)
    FILTER (?date < ?now) .
       

    BIND(YEAR(?date) as ?year)

   # get the label
   # ?genrer sc:name ?genre.
} GROUP BY ?genrer ?year 
HAVING (COUNT (DISTINCT ?filmr) > 50)
LIMIT 500


"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('genrer', 'http://www.wikidata.org/entity/Q645928'), ('callret-1', 'biographical film'), ('callret-2', '2018')]
# [('genrer', 'http://www.wikidata.org/entity/Q130232'), ('callret-1', 'drama'), ('callret-2', '2019')]
# [('genrer', 'http://www.wikidata.org/entity/Q842256'), ('callret-1', 'musical film'), ('callret-2', '2003')]
# [('genrer', 'http://www.wikidata.org/entity/Q471839'), ('callret-1', 'science fiction film'), ('callret-2', '2011')]
# [('genrer', 'http://www.wikidata.org/entity/Q859369'), ('callret-1', 'comedy-drama'), ('callret-2', '2004')]
# [('genrer', 'http://www.wikidata.org/entity/Q2484376'), ('callret-1', 'thriller film'), ('callret-2', '2004')]
# [('genrer', 'http://www.wikidata.org/entity/Q459290'), ('callret-1', 'independent film'), ('callret-2', '2016')]
# [('genrer', 'http://www.wikidata.org/entity/Q130232'), ('callret-1', 'drama'), ('callret-2', '2009')]
# [('genrer', 'http://www.wikidata.org/entity/Q859369'), ('callret-1', 'comedy-drama'), ('callret-2', '2009')]
# [('genrer', 'http://www.wikidata.org/entity/Q157443'), ('callret-1', 'comedy film'), ('callret-2', '2004')]
# [('genrer', 'http://www.wikidata.org/entity/Q1146335'), ('callret-1', 'teen film'), ('callret-2', '2007')]
# [('genrer', 'http://www.wikidata.org/entity/Q471839'), ('callret-1', 'science fiction film'), ('callret-2', '2014')]
# [('genrer', 'http://www.wikidata.org/entity/Q319221'), ('callret-1', 'adventure film'), ('callret-2', '2017')]
# [('genrer', 'http://www.wikidata.org/entity/Q859369'), ('callret-1', 'comedy-drama'), ('callret-2', '2014')]
# [('genrer', 'http://www.wikidata.org/entity/Q645928'), ('callret-1', 'biographical film'), ('callret-2', '2019')]
# [('genrer', 'http://www.wikidata.org/entity/Q20442589'), ('callret-1', 'LGBT-related film'), ('callret-2', '2011')]
# [('genrer', 'http://www.wikidata.org/entity/Q130232'), ('callret-1', 'drama'), ('callret-2', '2006')]
# [('genrer', 'http://www.wikidata.org/entity/Q369747'), ('callret-1', 'war film'), ('callret-2', '2016')]
# [('genrer', 'http://www.wikidata.org/entity/Q2484376'), ('callret-1', 'thriller film'), ('callret-2', '2013')]
# [('genrer', 'http://www.wikidata.org/entity/Q157394'), ('callret-1', 'fantasy film'), ('callret-2', '2014')]
# [('genrer', 'http://www.wikidata.org/entity/Q1054574'), ('callret-1', 'romance film'), ('callret-2', '2008')]
# [('genrer', 'http://www.wikidata.org/entity/Q1054574'), ('callret-1', 'romance film'), ('callret-2', '2019')]
# [('genrer', 'http://www.wikidata.org/entity/Q842256'), ('callret-1', 'musical film'), ('callret-2', '2017')]
# [('genrer', 'http://www.wikidata.org/entity/Q860626'), ('callret-1', 'romantic comedy'), ('callret-2', '2013')]
# [('genrer', 'http://www.wikidata.org/entity/Q188473'), ('callret-1', 'action film'), ('callret-2', '2015')]
# [('genrer', 'http://www.wikidata.org/entity/Q200092'), ('callret-1', 'horror film'), ('callret-2', '2004')]
# [('genrer', 'http://www.wikidata.org/entity/Q2484376'), ('callret-1', 'thriller film'), ('callret-2', '2019')]
# [('genrer', 'http://www.wikidata.org/entity/Q860626'), ('callret-1', 'romantic comedy'), ('callret-2', '2018')]
# [('genrer', 'http://www.wikidata.org/entity/Q369747'), ('callret-1', 'war film'), ('callret-2', '2011')]
# [('genrer', 'http://www.wikidata.org/entity/Q157443'), ('callret-1', 'comedy film'), ('callret-2', '2012')]
# [('genrer', 'http://www.wikidata.org/entity/Q20442589'), ('callret-1', 'LGBT-related film'), ('callret-2', '2013')]
# [('genrer', 'http://www.wikidata.org/entity/Q645928'), ('callret-1', 'biographical film'), ('callret-2', '2013')]
# [('genrer', 'http://www.wikidata.org/entity/Q2484376'), ('callret-1', 'thriller film'), ('callret-2', '2017')]
# [('genrer', 'http://www.wikidata.org/entity/Q52162262'), ('callret-1', 'film based on literature'), ('callret-2', '2013')]
# [('genrer', 'http://www.wikidata.org/entity/Q157394'), ('callret-1', 'fantasy film'), ('callret-2', '2017')]
# [('genrer', 'http://www.wikidata.org/entity/Q188473'), ('callret-1', 'action film'), ('callret-2', '2018')]
# [('genrer', 'http://www.wikidata.org/entity/Q842256'), ('callret-1', 'musical film'), ('callret-2', '2015')]
# [('genrer', 'http://www.wikidata.org/entity/Q645928'), ('callret-1', 'biographical film'), ('callret-2', '2020')]
# [('genrer', 'http://www.wikidata.org/entity/Q200092'), ('callret-1', 'horror film'), ('callret-2', '2011')]
# [('genrer', 'http://www.wikidata.org/entity/Q319221'), ('callret-1', 'adventure film'), ('callret-2', '2020')]
# [('genrer', 'http://www.wikidata.org/entity/Q157394'), ('callret-1', 'fantasy film'), ('callret-2', '2006')]
# [('genrer', 'http://www.wikidata.org/entity/Q188473'), ('callret-1', 'action film'), ('callret-2', '2019')]
# [('genrer', 'http://www.wikidata.org/entity/Q20442589'), ('callret-1', 'LGBT-related film'), ('callret-2', '2005')]
# [('genrer', 'http://www.wikidata.org/entity/Q1146335'), ('callret-1', 'teen film'), ('callret-2', '2008')]
# [('genrer', 'http://www.wikidata.org/entity/Q645928'), ('callret-1', 'biographical film'), ('callret-2', '2014')]
# [('genrer', 'http://www.wikidata.org/entity/Q200092'), ('callret-1', 'horror film'), ('callret-2', '2007')]
# [('genrer', 'http://www.wikidata.org/entity/Q157443'), ('callret-1', 'comedy film'), ('callret-2', '2003')]
# [('genrer', 'http://www.wikidata.org/entity/Q859369'), ('callret-1', 'comedy-drama'), ('callret-2', '2020')]
# [('genrer', 'http://www.wikidata.org/entity/Q130232'), ('callret-1', 'drama'), ('callret-2', '2016')]
# [('genrer', 'http://www.wikidata.org/entity/Q1054574'), ('callret-1', 'romance film'), ('callret-2', '2012')]
# [('genrer', 'http://www.wikidata.org/entity/Q319221'), ('callret-1', 'adventure film'), ('callret-2', '2009')]
# [('genrer', 'http://www.wikidata.org/entity/Q471839'), ('callret-1', 'science fiction film'), ('callret-2', '2004')]
# [('genrer', 'http://www.wikidata.org/entity/Q2484376'), ('callret-1', 'thriller film'), ('callret-2', '2008')]
# [('genrer', 'http://www.wikidata.org/entity/Q200092'), ('callret-1', 'horror film'), ('callret-2', '2014')]
# [('genrer', 'http://www.wikidata.org/entity/Q157394'), ('callret-1', 'fantasy film'), ('callret-2', '2009')]
# [('genrer', 'http://www.wikidata.org/entity/Q860626'), ('callret-1', 'romantic comedy'), ('callret-2', '2007')]
# [('genrer', 'http://www.wikidata.org/entity/Q93204'), ('callret-1', 'documentary film'), ('callret-2', '2013')]
# [('genrer', 'http://www.wikidata.org/entity/Q93204'), ('callret-1', 'documentary film'), ('callret-2', '2012')]
# [('genrer', 'http://www.wikidata.org/entity/Q20442589'), ('callret-1', 'LGBT-related film'), ('callret-2', '2007')]
# [('genrer', 'http://www.wikidata.org/entity/Q1200678'), ('callret-1', 'mystery film'), ('callret-2', '2018')]
# [('genrer', 'http://www.wikidata.org/entity/Q200092'), ('callret-1', 'horror film'), ('callret-2', '2018')]
# [('genrer', 'http://www.wikidata.org/entity/Q93204'), ('callret-1', 'documentary film'), ('callret-2', '2011')]
# [('genrer', 'http://www.wikidata.org/entity/Q842256'), ('callret-1', 'musical film'), ('callret-2', '2006')]
# [('genrer', 'http://www.wikidata.org/entity/Q93204'), ('callret-1', 'documentary film'), ('callret-2', '2010')]
# [('genrer', 'http://www.wikidata.org/entity/Q93204'), ('callret-1', 'documentary film'), ('callret-2', '2009')]
# [('genrer', 'http://www.wikidata.org/entity/Q645928'), ('callret-1', 'biographical film'), ('callret-2', '2008')]
# [('genrer', 'http://www.wikidata.org/entity/Q130232'), ('callret-1', 'drama'), ('callret-2', '2013')]
# [('genrer', 'http://www.wikidata.org/entity/Q52207399'), ('callret-1', 'film based on a novel'), ('callret-2', '2016')]
# [('genrer', 'http://www.wikidata.org/entity/Q860626'), ('callret-1', 'romantic comedy'), ('callret-2', '2012')]
# [('genrer', 'http://www.wikidata.org/entity/Q842256'), ('callret-1', 'musical film'), ('callret-2', '2004')]
# [('genrer', 'http://www.wikidata.org/entity/Q319221'), ('callret-1', 'adventure film'), ('callret-2', '2018')]
# [('genrer', 'http://www.wikidata.org/entity/Q471839'), ('callret-1', 'science fiction film'), ('callret-2', '2007')]
# [('genrer', 'http://www.wikidata.org/entity/Q860626'), ('callret-1', 'romantic comedy'), ('callret-2', '2017')]
# [('genrer', 'http://www.wikidata.org/entity/Q130232'), ('callret-1', 'drama'), ('callret-2', '2003')]
# [('genrer', 'http://www.wikidata.org/entity/Q1054574'), ('callret-1', 'romance film'), ('callret-2', '2007')]
# [('genrer', 'http://www.wikidata.org/entity/Q157443'), ('callret-1', 'comedy film'), ('callret-2', '2011')]
# [('genrer', 'http://www.wikidata.org/entity/Q959790'), ('callret-1', 'crime film'), ('callret-2', '2020')]
# [('genrer', 'http://www.wikidata.org/entity/Q859369'), ('callret-1', 'comedy-drama'), ('callret-2', '2005')]
# [('genrer', 'http://www.wikidata.org/entity/Q188473'), ('callret-1', 'action film'), ('callret-2', '2001')]
# [('genrer', 'http://www.wikidata.org/entity/Q2484376'), ('callret-1', 'thriller film'), ('callret-2', '2012')]
# [('genrer', 'http://www.wikidata.org/entity/Q645928'), ('callret-1', 'biographical film'), ('callret-2', '2015')]
# [('genrer', 'http://www.wikidata.org/entity/Q2143665'), ('callret-1', "children's film"), ('callret-2', '2004')]
# [('genrer', 'http://www.wikidata.org/entity/Q157394'), ('callret-1', 'fantasy film'), ('callret-2', '2016')]
# [('genrer', 'http://www.wikidata.org/entity/Q2143665'), ('callret-1', "children's film"), ('callret-2', '2006')]
# [('genrer', 'http://www.wikidata.org/entity/Q859369'), ('callret-1', 'comedy-drama'), ('callret-2', '2010')]
# [('genrer', 'http://www.wikidata.org/entity/Q200092'), ('callret-1', 'horror film'), ('callret-2', '2021')]
# [('genrer', 'http://www.wikidata.org/entity/Q369747'), ('callret-1', 'war film'), ('callret-2', '2018')]
# [('genrer', 'http://www.wikidata.org/entity/Q645928'), ('callret-1', 'biographical film'), ('callret-2', '2009')]
# [('genrer', 'http://www.wikidata.org/entity/Q1146335'), ('callret-1', 'teen film'), ('callret-2', '2004')]
# [('genrer', 'http://www.wikidata.org/entity/Q188473'), ('callret-1', 'action film'), ('callret-2', '2004')]
# [('genrer', 'http://www.wikidata.org/entity/Q52207399'), ('callret-1', 'film based on a novel'), ('callret-2', '2015')]
# [('genrer', 'http://www.wikidata.org/entity/Q1146335'), ('callret-1', 'teen film'), ('callret-2', '2009')]
# [('genrer', 'http://www.wikidata.org/entity/Q859369'), ('callret-1', 'comedy-drama'), ('callret-2', '2015')]
# [('genrer', 'http://www.wikidata.org/entity/Q959790'), ('callret-1', 'crime film'), ('callret-2', '2018')]
# [('genrer', 'http://www.wikidata.org/entity/Q188473'), ('callret-1', 'action film'), ('callret-2', '2021')]
# [('genrer', 'http://www.wikidata.org/entity/Q471839'), ('callret-1', 'science fiction film'), ('callret-2', '2015')]
# [('genrer', 'http://www.wikidata.org/entity/Q471839'), ('callret-1', 'science fiction film'), ('callret-2', '2018')]
# [('genrer', 'http://www.wikidata.org/entity/Q157443'), ('callret-1', 'comedy film'), ('callret-2', '2002')]
# [('genrer', 'http://www.wikidata.org/entity/Q157394'), ('callret-1', 'fantasy film'), ('callret-2', '2019')]
# [('genrer', 'http://www.wikidata.org/entity/Q157443'), ('callret-1', 'comedy film'), ('callret-2', '2019')]
# [('genrer', 'http://www.wikidata.org/entity/Q860626'), ('callret-1', 'romantic comedy'), ('callret-2', '2006')]
# [('genrer', 'http://www.wikidata.org/entity/Q2484376'), ('callret-1', 'thriller film'), ('callret-2', '2003')]
# [('genrer', 'http://www.wikidata.org/entity/Q959790'), ('callret-1', 'crime film'), ('callret-2', '2016')]
# [('genrer', 'http://www.wikidata.org/entity/Q185529'), ('callret-1', 'pornographic film'), ('callret-2', '2007')]
# [('genrer', 'http://www.wikidata.org/entity/Q645928'), ('callret-1', 'biographical film'), ('callret-2', '2016')]
# [('genrer', 'http://www.wikidata.org/entity/Q842256'), ('callret-1', 'musical film'), ('callret-2', '2018')]
# [('genrer', 'http://www.wikidata.org/entity/Q157394'), ('callret-1', 'fantasy film'), ('callret-2', '2008')]
# [('genrer', 'http://www.wikidata.org/entity/Q1339864'), ('callret-1', 'sport film'), ('callret-2', '2016')]
# [('genrer', 'http://www.wikidata.org/entity/Q93204'), ('callret-1', 'documentary film'), ('callret-2', '2008')]
# [('genrer', 'http://www.wikidata.org/entity/Q93204'), ('callret-1', 'documentary film'), ('callret-2', '2007')]
# [('genrer', 'http://www.wikidata.org/entity/Q93204'), ('callret-1', 'documentary film'), ('callret-2', '2006')]
# [('genrer', 'http://www.wikidata.org/entity/Q1054574'), ('callret-1', 'romance film'), ('callret-2', '2011')]
# [('genrer', 'http://www.wikidata.org/entity/Q842256'), ('callret-1', 'musical film'), ('callret-2', '2016')]
# [('genrer', 'http://www.wikidata.org/entity/Q93204'), ('callret-1', 'documentary film'), ('callret-2', '2005')]
# [('genrer', 'http://www.wikidata.org/entity/Q93204'), ('callret-1', 'documentary film'), ('callret-2', '2004')]
# [('genrer', 'http://www.wikidata.org/entity/Q645928'), ('callret-1', 'biographical film'), ('callret-2', '2010')]
# [('genrer', 'http://www.wikidata.org/entity/Q20442589'), ('callret-1', 'LGBT-related film'), ('callret-2', '2014')]
# [('genrer', 'http://www.wikidata.org/entity/Q1200678'), ('callret-1', 'mystery film'), ('callret-2', '2016')]
# [('genrer', 'http://www.wikidata.org/entity/Q860626'), ('callret-1', 'romantic comedy'), ('callret-2', '2011')]
# [('genrer', 'http://www.wikidata.org/entity/Q959790'), ('callret-1', 'crime film'), ('callret-2', '2014')]
# [('genrer', 'http://www.wikidata.org/entity/Q319221'), ('callret-1', 'adventure film'), ('callret-2', '2010')]
# [('genrer', 'http://www.wikidata.org/entity/Q2484376'), ('callret-1', 'thriller film'), ('callret-2', '2007')]
# [('genrer', 'http://www.wikidata.org/entity/Q130232'), ('callret-1', 'drama'), ('callret-2', '2020')]
# [('genrer', 'http://www.wikidata.org/entity/Q157443'), ('callret-1', 'comedy film'), ('callret-2', '2010')]
# [('genrer', 'http://www.wikidata.org/entity/Q52207399'), ('callret-1', 'film based on a novel'), ('callret-2', '2013')]
# [('genrer', 'http://www.wikidata.org/entity/Q645928'), ('callret-1', 'biographical film'), ('callret-2', '2004')]
# [('genrer', 'http://www.wikidata.org/entity/Q645928'), ('callret-1', 'biographical film'), ('callret-2', '2017')]
# [('genrer', 'http://www.wikidata.org/entity/Q860626'), ('callret-1', 'romantic comedy'), ('callret-2', '2016')]
# [('genrer', 'http://www.wikidata.org/entity/Q157394'), ('callret-1', 'fantasy film'), ('callret-2', '2011')]
# [('genrer', 'http://www.wikidata.org/entity/Q188473'), ('callret-1', 'action film'), ('callret-2', '2003')]
# [('genrer', 'http://www.wikidata.org/entity/Q130232'), ('callret-1', 'drama'), ('callret-2', '2010')]
# [('genrer', 'http://www.wikidata.org/entity/Q1146335'), ('callret-1', 'teen film'), ('callret-2', '2005')]
# [('genrer', 'http://www.wikidata.org/entity/Q369747'), ('callret-1', 'war film'), ('callret-2', '2004')]
# [('genrer', 'http://www.wikidata.org/entity/Q645928'), ('callret-1', 'biographical film'), ('callret-2', '2011')]
# [('genrer', 'http://www.wikidata.org/entity/Q959790'), ('callret-1', 'crime film'), ('callret-2', '2012')]
# [('genrer', 'http://www.wikidata.org/entity/Q20442589'), ('callret-1', 'LGBT-related film'), ('callret-2', '2016')]
# [('genrer', 'http://www.wikidata.org/entity/Q842256'), ('callret-1', 'musical film'), ('callret-2', '2009')]
# [('genrer', 'http://www.wikidata.org/entity/Q20442589'), ('callret-1', 'LGBT-related film'), ('callret-2', '2006')]
# [('genrer', 'http://www.wikidata.org/entity/Q1054574'), ('callret-1', 'romance film'), ('callret-2', '2015')]
# [('genrer', 'http://www.wikidata.org/entity/Q2484376'), ('callret-1', 'thriller film'), ('callret-2', '2016')]
# [('genrer', 'http://www.wikidata.org/entity/Q52207399'), ('callret-1', 'film based on a novel'), ('callret-2', '2012')]
# [('genrer', 'http://www.wikidata.org/entity/Q842256'), ('callret-1', 'musical film'), ('callret-2', '2007')]
# [('genrer', 'http://www.wikidata.org/entity/Q130232'), ('callret-1', 'drama'), ('callret-2', '2007')]
# [('genrer', 'http://www.wikidata.org/entity/Q157443'), ('callret-1', 'comedy film'), ('callret-2', '2001')]
# [('genrer', 'http://www.wikidata.org/entity/Q188473'), ('callret-1', 'action film'), ('callret-2', '2007')]
# [('genrer', 'http://www.wikidata.org/entity/Q471839'), ('callret-1', 'science fiction film'), ('callret-2', '2005')]
# [('genrer', 'http://www.wikidata.org/entity/Q200092'), ('callret-1', 'horror film'), ('callret-2', '2002')]
# [('genrer', 'http://www.wikidata.org/entity/Q20442589'), ('callret-1', 'LGBT-related film'), ('callret-2', '2008')]
# [('genrer', 'http://www.wikidata.org/entity/Q157443'), ('callret-1', 'comedy film'), ('callret-2', '2018')]
# [('genrer', 'http://www.wikidata.org/entity/Q959790'), ('callret-1', 'crime film'), ('callret-2', '2010')]
# [('genrer', 'http://www.wikidata.org/entity/Q860626'), ('callret-1', 'romantic comedy'), ('callret-2', '2005')]
# [('genrer', 'http://www.wikidata.org/entity/Q2143665'), ('callret-1', "children's film"), ('callret-2', '2005')]
# [('genrer', 'http://www.wikidata.org/entity/Q645928'), ('callret-1', 'biographical film'), ('callret-2', '2005')]
# [('genrer', 'http://www.wikidata.org/entity/Q188473'), ('callret-1', 'action film'), ('callret-2', '2010')]
# [('genrer', 'http://www.wikidata.org/entity/Q471839'), ('callret-1', 'science fiction film'), ('callret-2', '2008')]
# [('genrer', 'http://www.wikidata.org/entity/Q860626'), ('callret-1', 'romantic comedy'), ('callret-2', '2010')]
# [('genrer', 'http://www.wikidata.org/entity/Q859369'), ('callret-1', 'comedy-drama'), ('callret-2', '2006')]
# [('genrer', 'http://www.wikidata.org/entity/Q1200678'), ('callret-1', 'mystery film'), ('callret-2', '2017')]
# [('genrer', 'http://www.wikidata.org/entity/Q645928'), ('callret-1', 'biographical film'), ('callret-2', '2012')]
# [('genrer', 'http://www.wikidata.org/entity/Q188473'), ('callret-1', 'action film'), ('callret-2', '2011')]
# [('genrer', 'http://www.wikidata.org/entity/Q319221'), ('callret-1', 'adventure film'), ('callret-2', '2008')]
# [('genrer', 'http://www.wikidata.org/entity/Q200092'), ('callret-1', 'horror film'), ('callret-2', '2005')]
# [('genrer', 'http://www.wikidata.org/entity/Q959790'), ('callret-1', 'crime film'), ('callret-2', '2008')]
# [('genrer', 'http://www.wikidata.org/entity/Q2143665'), ('callret-1', "children's film"), ('callret-2', '2009')]
# [('genrer', 'http://www.wikidata.org/entity/Q859369'), ('callret-1', 'comedy-drama'), ('callret-2', '2011')]
# [('genrer', 'http://www.wikidata.org/entity/Q1054574'), ('callret-1', 'romance film'), ('callret-2', '2010')]
# [('genrer', 'http://www.wikidata.org/entity/Q471839'), ('callret-1', 'science fiction film'), ('callret-2', '2016')]
# [('genrer', 'http://www.wikidata.org/entity/Q2143665'), ('callret-1', "children's film"), ('callret-2', '2007')]
# [('genrer', 'http://www.wikidata.org/entity/Q2143665'), ('callret-1', "children's film"), ('callret-2', '2011')]
# [('genrer', 'http://www.wikidata.org/entity/Q157443'), ('callret-1', 'comedy film'), ('callret-2', '2009')]
# [('genrer', 'http://www.wikidata.org/entity/Q645928'), ('callret-1', 'biographical film'), ('callret-2', '2006')]
# [('genrer', 'http://www.wikidata.org/entity/Q859369'), ('callret-1', 'comedy-drama'), ('callret-2', '2016')]
# [('genrer', 'http://www.wikidata.org/entity/Q860626'), ('callret-1', 'romantic comedy'), ('callret-2', '2015')]
# [('genrer', 'http://www.wikidata.org/entity/Q842256'), ('callret-1', 'musical film'), ('callret-2', '2019')]
# [('genrer', 'http://www.wikidata.org/entity/Q188473'), ('callret-1', 'action film'), ('callret-2', '2014')]
# [('genrer', 'http://www.wikidata.org/entity/Q93204'), ('callret-1', 'documentary film'), ('callret-2', '2021')]
# [('genrer', 'http://www.wikidata.org/entity/Q17013749'), ('callret-1', 'historical film'), ('callret-2', '2020')]
# [('genrer', 'http://www.wikidata.org/entity/Q93204'), ('callret-1', 'documentary film'), ('callret-2', '2020')]
# [('genrer', 'http://www.wikidata.org/entity/Q93204'), ('callret-1', 'documentary film'), ('callret-2', '2019')]
# [('genrer', 'http://www.wikidata.org/entity/Q93204'), ('callret-1', 'documentary film'), ('callret-2', '2018')]
# [('genrer', 'http://www.wikidata.org/entity/Q369747'), ('callret-1', 'war film'), ('callret-2', '2015')]
# [('genrer', 'http://www.wikidata.org/entity/Q17013749'), ('callret-1', 'historical film'), ('callret-2', '2019')]
# [('genrer', 'http://www.wikidata.org/entity/Q93204'), ('callret-1', 'documentary film'), ('callret-2', '2017')]
# [('genrer', 'http://www.wikidata.org/entity/Q471839'), ('callret-1', 'science fiction film'), ('callret-2', '2019')]
# [('genrer', 'http://www.wikidata.org/entity/Q959790'), ('callret-1', 'crime film'), ('callret-2', '2006')]
# [('genrer', 'http://www.wikidata.org/entity/Q200092'), ('callret-1', 'horror film'), ('callret-2', '2012')]
# [('genrer', 'http://www.wikidata.org/entity/Q130232'), ('callret-1', 'drama'), ('callret-2', '2017')]
# [('genrer', 'http://www.wikidata.org/entity/Q2484376'), ('callret-1', 'thriller film'), ('callret-2', '2011')]
# [('genrer', 'http://www.wikidata.org/entity/Q1054574'), ('callret-1', 'romance film'), ('callret-2', '2003')]
# [('genrer', 'http://www.wikidata.org/entity/Q319221'), ('callret-1', 'adventure film'), ('callret-2', '2011')]
# [('genrer', 'http://www.wikidata.org/entity/Q200092'), ('callret-1', 'horror film'), ('callret-2', '2008')]
# [('genrer', 'http://www.wikidata.org/entity/Q157394'), ('callret-1', 'fantasy film'), ('callret-2', '2013')]
# [('genrer', 'http://www.wikidata.org/entity/Q959790'), ('callret-1', 'crime film'), ('callret-2', '2004')]
# [('genrer', 'http://www.wikidata.org/entity/Q157443'), ('callret-1', 'comedy film'), ('callret-2', '2017')]
# [('genrer', 'http://www.wikidata.org/entity/Q130232'), ('callret-1', 'drama'), ('callret-2', '2014')]
# [('genrer', 'http://www.wikidata.org/entity/Q200092'), ('callret-1', 'horror film'), ('callret-2', '2015')]
# [('genrer', 'http://www.wikidata.org/entity/Q20442589'), ('callret-1', 'LGBT-related film'), ('callret-2', '2015')]
# [('genrer', 'http://www.wikidata.org/entity/Q645928'), ('callret-1', 'biographical film'), ('callret-2', '2007')]
# [('genrer', 'http://www.wikidata.org/entity/Q860626'), ('callret-1', 'romantic comedy'), ('callret-2', '2004')]
# [('genrer', 'http://www.wikidata.org/entity/Q2484376'), ('callret-1', 'thriller film'), ('callret-2', '2015')]
# [('genrer', 'http://www.wikidata.org/entity/Q130232'), ('callret-1', 'drama'), ('callret-2', '2004')]
# [('genrer', 'http://www.wikidata.org/entity/Q1054574'), ('callret-1', 'romance film'), ('callret-2', '2014')]
# [('genrer', 'http://www.wikidata.org/entity/Q860626'), ('callret-1', 'romantic comedy'), ('callret-2', '2009')]
# [('genrer', 'http://www.wikidata.org/entity/Q200092'), ('callret-1', 'horror film'), ('callret-2', '2019')]
# [('genrer', 'http://www.wikidata.org/entity/Q859369'), ('callret-1', 'comedy-drama'), ('callret-2', '2017')]
# [('genrer', 'http://www.wikidata.org/entity/Q842256'), ('callret-1', 'musical film'), ('callret-2', '2008')]
# [('genrer', 'http://www.wikidata.org/entity/Q959790'), ('callret-1', 'crime film'), ('callret-2', '2002')]
# [('genrer', 'http://www.wikidata.org/entity/Q188473'), ('callret-1', 'action film'), ('callret-2', '2013')]
# [('genrer', 'http://www.wikidata.org/entity/Q1200678'), ('callret-1', 'mystery film'), ('callret-2', '2015')]
# [('genrer', 'http://www.wikidata.org/entity/Q52207399'), ('callret-1', 'film based on a novel'), ('callret-2', '2008')]
# [('genrer', 'http://www.wikidata.org/entity/Q2484376'), ('callret-1', 'thriller film'), ('callret-2', '2002')]
# [('genrer', 'http://www.wikidata.org/entity/Q842256'), ('callret-1', 'musical film'), ('callret-2', '2010')]
# [('genrer', 'http://www.wikidata.org/entity/Q959790'), ('callret-1', 'crime film'), ('callret-2', '2019')]
# [('genrer', 'http://www.wikidata.org/entity/Q157394'), ('callret-1', 'fantasy film'), ('callret-2', '2005')]
# [('genrer', 'http://www.wikidata.org/entity/Q157443'), ('callret-1', 'comedy film'), ('callret-2', '2008')]
# [('genrer', 'http://www.wikidata.org/entity/Q130232'), ('callret-1', 'drama'), ('callret-2', '2001')]
# [('genrer', 'http://www.wikidata.org/entity/Q20442589'), ('callret-1', 'LGBT-related film'), ('callret-2', '2017')]
# [('genrer', 'http://www.wikidata.org/entity/Q959790'), ('callret-1', 'crime film'), ('callret-2', '2015')]
# [('genrer', 'http://www.wikidata.org/entity/Q93204'), ('callret-1', 'documentary film'), ('callret-2', '2016')]
# [('genrer', 'http://www.wikidata.org/entity/Q319221'), ('callret-1', 'adventure film'), ('callret-2', '2014')]
# [('genrer', 'http://www.wikidata.org/entity/Q93204'), ('callret-1', 'documentary film'), ('callret-2', '2015')]
# [('genrer', 'http://www.wikidata.org/entity/Q93204'), ('callret-1', 'documentary film'), ('callret-2', '2014')]
# [('genrer', 'http://www.wikidata.org/entity/Q471839'), ('callret-1', 'science fiction film'), ('callret-2', '2006')]
# [('genrer', 'http://www.wikidata.org/entity/Q959790'), ('callret-1', 'crime film'), ('callret-2', '2017')]
# [('genrer', 'http://www.wikidata.org/entity/Q2484376'), ('callret-1', 'thriller film'), ('callret-2', '2006')]
# [('genrer', 'http://www.wikidata.org/entity/Q1054574'), ('callret-1', 'romance film'), ('callret-2', '2018')]
# [('genrer', 'http://www.wikidata.org/entity/Q859369'), ('callret-1', 'comedy-drama'), ('callret-2', '2002')]
# [('genrer', 'http://www.wikidata.org/entity/Q188473'), ('callret-1', 'action film'), ('callret-2', '2017')]
# [('genrer', 'http://www.wikidata.org/entity/Q959790'), ('callret-1', 'crime film'), ('callret-2', '2013')]
# [('genrer', 'http://www.wikidata.org/entity/Q645928'), ('callret-1', 'biographical film'), ('callret-2', '2002')]
# [('genrer', 'http://www.wikidata.org/entity/Q1054574'), ('callret-1', 'romance film'), ('callret-2', '2002')]
# [('genrer', 'http://www.wikidata.org/entity/Q859369'), ('callret-1', 'comedy-drama'), ('callret-2', '2007')]
# [('genrer', 'http://www.wikidata.org/entity/Q471839'), ('callret-1', 'science fiction film'), ('callret-2', '2009')]
# [('genrer', 'http://www.wikidata.org/entity/Q459290'), ('callret-1', 'independent film'), ('callret-2', '2008')]
# [('genrer', 'http://www.wikidata.org/entity/Q471839'), ('callret-1', 'science fiction film'), ('callret-2', '2012')]
# [('genrer', 'http://www.wikidata.org/entity/Q157443'), ('callret-1', 'comedy film'), ('callret-2', '2016')]
# [('genrer', 'http://www.wikidata.org/entity/Q20442589'), ('callret-1', 'LGBT-related film'), ('callret-2', '2009')]
# [('genrer', 'http://www.wikidata.org/entity/Q188473'), ('callret-1', 'action film'), ('callret-2', '2020')]
# [('genrer', 'http://www.wikidata.org/entity/Q859369'), ('callret-1', 'comedy-drama'), ('callret-2', '2012')]
# [('genrer', 'http://www.wikidata.org/entity/Q1200678'), ('callret-1', 'mystery film'), ('callret-2', '2011')]
# [('genrer', 'http://www.wikidata.org/entity/Q1146335'), ('callret-1', 'teen film'), ('callret-2', '2002')]
# [('genrer', 'http://www.wikidata.org/entity/Q157443'), ('callret-1', 'comedy film'), ('callret-2', '2021')]
# [('genrer', 'http://www.wikidata.org/entity/Q860626'), ('callret-1', 'romantic comedy'), ('callret-2', '2003')]
# [('genrer', 'http://www.wikidata.org/entity/Q471839'), ('callret-1', 'science fiction film'), ('callret-2', '2017')]
# [('genrer', 'http://www.wikidata.org/entity/Q959790'), ('callret-1', 'crime film'), ('callret-2', '2011')]
# [('genrer', 'http://www.wikidata.org/entity/Q130232'), ('callret-1', 'drama'), ('callret-2', '2021')]
# [('genrer', 'http://www.wikidata.org/entity/Q157394'), ('callret-1', 'fantasy film'), ('callret-2', '2015')]
# [('genrer', 'http://www.wikidata.org/entity/Q1054574'), ('callret-1', 'romance film'), ('callret-2', '2013')]
# [('genrer', 'http://www.wikidata.org/entity/Q860626'), ('callret-1', 'romantic comedy'), ('callret-2', '2008')]
# [('genrer', 'http://www.wikidata.org/entity/Q130232'), ('callret-1', 'drama'), ('callret-2', '2011')]
# [('genrer', 'http://www.wikidata.org/entity/Q2484376'), ('callret-1', 'thriller film'), ('callret-2', '2021')]
# [('genrer', 'http://www.wikidata.org/entity/Q2143665'), ('callret-1', "children's film"), ('callret-2', '2010')]
# [('genrer', 'http://www.wikidata.org/entity/Q157394'), ('callret-1', 'fantasy film'), ('callret-2', '2018')]
# [('genrer', 'http://www.wikidata.org/entity/Q471839'), ('callret-1', 'science fiction film'), ('callret-2', '2020')]
# [('genrer', 'http://www.wikidata.org/entity/Q157443'), ('callret-1', 'comedy film'), ('callret-2', '2007')]
# [('genrer', 'http://www.wikidata.org/entity/Q369747'), ('callret-1', 'war film'), ('callret-2', '2012')]
# [('genrer', 'http://www.wikidata.org/entity/Q959790'), ('callret-1', 'crime film'), ('callret-2', '2009')]
# [('genrer', 'http://www.wikidata.org/entity/Q130232'), ('callret-1', 'drama'), ('callret-2', '2018')]
# [('genrer', 'http://www.wikidata.org/entity/Q130232'), ('callret-1', 'drama'), ('callret-2', '2008')]
# [('genrer', 'http://www.wikidata.org/entity/Q1054574'), ('callret-1', 'romance film'), ('callret-2', '2006')]
# [('genrer', 'http://www.wikidata.org/entity/Q20442589'), ('callret-1', 'LGBT-related film'), ('callret-2', '2003')]
# [('genrer', 'http://www.wikidata.org/entity/Q369747'), ('callret-1', 'war film'), ('callret-2', '2008')]
# [('genrer', 'http://www.wikidata.org/entity/Q842256'), ('callret-1', 'musical film'), ('callret-2', '2011')]
# [('genrer', 'http://www.wikidata.org/entity/Q188473'), ('callret-1', 'action film'), ('callret-2', '2002')]
# [('genrer', 'http://www.wikidata.org/entity/Q959790'), ('callret-1', 'crime film'), ('callret-2', '2007')]
# [('genrer', 'http://www.wikidata.org/entity/Q157394'), ('callret-1', 'fantasy film'), ('callret-2', '2007')]
# [('genrer', 'http://www.wikidata.org/entity/Q842256'), ('callret-1', 'musical film'), ('callret-2', '2013')]
# [('genrer', 'http://www.wikidata.org/entity/Q200092'), ('callret-1', 'horror film'), ('callret-2', '2003')]
# [('genrer', 'http://www.wikidata.org/entity/Q157394'), ('callret-1', 'fantasy film'), ('callret-2', '2010')]
# [('genrer', 'http://www.wikidata.org/entity/Q860626'), ('callret-1', 'romantic comedy'), ('callret-2', '2002')]
# [('genrer', 'http://www.wikidata.org/entity/Q859369'), ('callret-1', 'comedy-drama'), ('callret-2', '2018')]
# [('genrer', 'http://www.wikidata.org/entity/Q157443'), ('callret-1', 'comedy film'), ('callret-2', '2015')]
# [('genrer', 'http://www.wikidata.org/entity/Q319221'), ('callret-1', 'adventure film'), ('callret-2', '2015')]
# [('genrer', 'http://www.wikidata.org/entity/Q1146335'), ('callret-1', 'teen film'), ('callret-2', '2010')]
# [('genrer', 'http://www.wikidata.org/entity/Q2484376'), ('callret-1', 'thriller film'), ('callret-2', '2010')]
# [('genrer', 'http://www.wikidata.org/entity/Q1054574'), ('callret-1', 'romance film'), ('callret-2', '2017')]
# [('genrer', 'http://www.wikidata.org/entity/Q185529'), ('callret-1', 'pornographic film'), ('callret-2', '2008')]
# [('genrer', 'http://www.wikidata.org/entity/Q959790'), ('callret-1', 'crime film'), ('callret-2', '2005')]
# [('genrer', 'http://www.wikidata.org/entity/Q157443'), ('callret-1', 'comedy film'), ('callret-2', '2020')]
# [('genrer', 'http://www.wikidata.org/entity/Q188473'), ('callret-1', 'action film'), ('callret-2', '2006')]
# [('genrer', 'http://www.wikidata.org/entity/Q20442589'), ('callret-1', 'LGBT-related film'), ('callret-2', '2018')]
# [('genrer', 'http://www.wikidata.org/entity/Q471839'), ('callret-1', 'science fiction film'), ('callret-2', '2002')]
# [('genrer', 'http://www.wikidata.org/entity/Q1200678'), ('callret-1', 'mystery film'), ('callret-2', '2014')]
# [('genrer', 'http://www.wikidata.org/entity/Q842256'), ('callret-1', 'musical film'), ('callret-2', '2002')]
# [('genrer', 'http://www.wikidata.org/entity/Q200092'), ('callret-1', 'horror film'), ('callret-2', '2010')]
# [('genrer', 'http://www.wikidata.org/entity/Q959790'), ('callret-1', 'crime film'), ('callret-2', '2003')]
# [('genrer', 'http://www.wikidata.org/entity/Q200092'), ('callret-1', 'horror film'), ('callret-2', '2006')]
# [('genrer', 'http://www.wikidata.org/entity/Q157443'), ('callret-1', 'comedy film'), ('callret-2', '2006')]
# [('genrer', 'http://www.wikidata.org/entity/Q2484376'), ('callret-1', 'thriller film'), ('callret-2', '2014')]
# [('genrer', 'http://www.wikidata.org/entity/Q1200678'), ('callret-1', 'mystery film'), ('callret-2', '2012')]
# [('genrer', 'http://www.wikidata.org/entity/Q471839'), ('callret-1', 'science fiction film'), ('callret-2', '2010')]
# [('genrer', 'http://www.wikidata.org/entity/Q157394'), ('callret-1', 'fantasy film'), ('callret-2', '2002')]
# [('genrer', 'http://www.wikidata.org/entity/Q859369'), ('callret-1', 'comedy-drama'), ('callret-2', '2003')]
# [('genrer', 'http://www.wikidata.org/entity/Q319221'), ('callret-1', 'adventure film'), ('callret-2', '2013')]
# [('genrer', 'http://www.wikidata.org/entity/Q2484376'), ('callret-1', 'thriller film'), ('callret-2', '2020')]
# [('genrer', 'http://www.wikidata.org/entity/Q200092'), ('callret-1', 'horror film'), ('callret-2', '2013')]
# [('genrer', 'http://www.wikidata.org/entity/Q859369'), ('callret-1', 'comedy-drama'), ('callret-2', '2008')]
# [('genrer', 'http://www.wikidata.org/entity/Q200092'), ('callret-1', 'horror film'), ('callret-2', '2017')]
# [('genrer', 'http://www.wikidata.org/entity/Q130232'), ('callret-1', 'drama'), ('callret-2', '2015')]
# [('genrer', 'http://www.wikidata.org/entity/Q471839'), ('callret-1', 'science fiction film'), ('callret-2', '2013')]
# [('genrer', 'http://www.wikidata.org/entity/Q157394'), ('callret-1', 'fantasy film'), ('callret-2', '2020')]
# [('genrer', 'http://www.wikidata.org/entity/Q859369'), ('callret-1', 'comedy-drama'), ('callret-2', '2013')]
# [('genrer', 'http://www.wikidata.org/entity/Q1054574'), ('callret-1', 'romance film'), ('callret-2', '2005')]
# [('genrer', 'http://www.wikidata.org/entity/Q17013749'), ('callret-1', 'historical film'), ('callret-2', '2018')]
# [('genrer', 'http://www.wikidata.org/entity/Q2484376'), ('callret-1', 'thriller film'), ('callret-2', '2018')]
# [('genrer', 'http://www.wikidata.org/entity/Q20442589'), ('callret-1', 'LGBT-related film'), ('callret-2', '2010')]
# [('genrer', 'http://www.wikidata.org/entity/Q200092'), ('callret-1', 'horror film'), ('callret-2', '2009')]
# [('genrer', 'http://www.wikidata.org/entity/Q17013749'), ('callret-1', 'historical film'), ('callret-2', '2017')]
# [('genrer', 'http://www.wikidata.org/entity/Q17013749'), ('callret-1', 'historical film'), ('callret-2', '2016')]
# [('genrer', 'http://www.wikidata.org/entity/Q130232'), ('callret-1', 'drama'), ('callret-2', '2005')]
# [('genrer', 'http://www.wikidata.org/entity/Q188473'), ('callret-1', 'action film'), ('callret-2', '2005')]
# [('genrer', 'http://www.wikidata.org/entity/Q20442589'), ('callret-1', 'LGBT-related film'), ('callret-2', '2012')]
# [('genrer', 'http://www.wikidata.org/entity/Q157443'), ('callret-1', 'comedy film'), ('callret-2', '2014')]
# [('genrer', 'http://www.wikidata.org/entity/Q2484376'), ('callret-1', 'thriller film'), ('callret-2', '2005')]
# [('genrer', 'http://www.wikidata.org/entity/Q130232'), ('callret-1', 'drama'), ('callret-2', '2012')]
# [('genrer', 'http://www.wikidata.org/entity/Q1200678'), ('callret-1', 'mystery film'), ('callret-2', '2010')]
# [('genrer', 'http://www.wikidata.org/entity/Q200092'), ('callret-1', 'horror film'), ('callret-2', '2020')]
# [('genrer', 'http://www.wikidata.org/entity/Q2143665'), ('callret-1', "children's film"), ('callret-2', '2015')]
# [('genrer', 'http://www.wikidata.org/entity/Q188473'), ('callret-1', 'action film'), ('callret-2', '2008')]
# [('genrer', 'http://www.wikidata.org/entity/Q1054574'), ('callret-1', 'romance film'), ('callret-2', '2016')]
# [('genrer', 'http://www.wikidata.org/entity/Q200092'), ('callret-1', 'horror film'), ('callret-2', '2016')]
# [('genrer', 'http://www.wikidata.org/entity/Q130232'), ('callret-1', 'drama'), ('callret-2', '2002')]
# [('genrer', 'http://www.wikidata.org/entity/Q2143665'), ('callret-1', "children's film"), ('callret-2', '2013')]
# [('genrer', 'http://www.wikidata.org/entity/Q842256'), ('callret-1', 'musical film'), ('callret-2', '2014')]
# [('genrer', 'http://www.wikidata.org/entity/Q157394'), ('callret-1', 'fantasy film'), ('callret-2', '2012')]
# [('genrer', 'http://www.wikidata.org/entity/Q20442589'), ('callret-1', 'LGBT-related film'), ('callret-2', '2002')]
# [('genrer', 'http://www.wikidata.org/entity/Q319221'), ('callret-1', 'adventure film'), ('callret-2', '2016')]
# [('genrer', 'http://www.wikidata.org/entity/Q188473'), ('callret-1', 'action film'), ('callret-2', '2009')]
# [('genrer', 'http://www.wikidata.org/entity/Q2484376'), ('callret-1', 'thriller film'), ('callret-2', '2009')]
# [('genrer', 'http://www.wikidata.org/entity/Q93204'), ('callret-1', 'documentary film'), ('callret-2', '2003')]
# [('genrer', 'http://www.wikidata.org/entity/Q93204'), ('callret-1', 'documentary film'), ('callret-2', '2002')]
# [('genrer', 'http://www.wikidata.org/entity/Q93204'), ('callret-1', 'documentary film'), ('callret-2', '2001')]
# [('genrer', 'http://www.wikidata.org/entity/Q157443'), ('callret-1', 'comedy film'), ('callret-2', '2005')]
# [('genrer', 'http://www.wikidata.org/entity/Q20442589'), ('callret-1', 'LGBT-related film'), ('callret-2', '2004')]
# [('genrer', 'http://www.wikidata.org/entity/Q188473'), ('callret-1', 'action film'), ('callret-2', '2012')]
# [('genrer', 'http://www.wikidata.org/entity/Q1146335'), ('callret-1', 'teen film'), ('callret-2', '2006')]
# [('genrer', 'http://www.wikidata.org/entity/Q1054574'), ('callret-1', 'romance film'), ('callret-2', '2009')]
# [('genrer', 'http://www.wikidata.org/entity/Q842256'), ('callret-1', 'musical film'), ('callret-2', '2012')]
# [('genrer', 'http://www.wikidata.org/entity/Q859369'), ('callret-1', 'comedy-drama'), ('callret-2', '2019')]
# [('genrer', 'http://www.wikidata.org/entity/Q860626'), ('callret-1', 'romantic comedy'), ('callret-2', '2014')]
# [('genrer', 'http://www.wikidata.org/entity/Q842256'), ('callret-1', 'musical film'), ('callret-2', '2005')]
# [('genrer', 'http://www.wikidata.org/entity/Q319221'), ('callret-1', 'adventure film'), ('callret-2', '2019')]
# [('genrer', 'http://www.wikidata.org/entity/Q157394'), ('callret-1', 'fantasy film'), ('callret-2', '2004')]
# [('genrer', 'http://www.wikidata.org/entity/Q1146335'), ('callret-1', 'teen film'), ('callret-2', '2012')]
# [('genrer', 'http://www.wikidata.org/entity/Q157443'), ('callret-1', 'comedy film'), ('callret-2', '2013')]
# [('genrer', 'http://www.wikidata.org/entity/Q1054574'), ('callret-1', 'romance film'), ('callret-2', '2020')]
# [('genrer', 'http://www.wikidata.org/entity/Q1361932'), ('callret-1', 'family film'), ('callret-2', '2016')]
# [('genrer', 'http://www.wikidata.org/entity/Q860626'), ('callret-1', 'romantic comedy'), ('callret-2', '2019')]
# [('genrer', 'http://www.wikidata.org/entity/Q188473'), ('callret-1', 'action film'), ('callret-2', '2016')]
# [('genrer', 'http://www.wikidata.org/entity/Q20442589'), ('callret-1', 'LGBT-related film'), ('callret-2', '2019')]
# [('genrer', 'http://www.wikidata.org/entity/Q1054574'), ('callret-1', 'romance film'), ('callret-2', '2004')]
# 351

# %%
queryString = """
SELECT DISTINCT ?genrer SAMPLE(?genre) (COUNT(DISTINCT ?filmr) as ?filmCount)
WHERE {

   # ?filmr wdt:P31 wd:Q11424;  # generic film
       # ?releaseDate ?date; # with a publication date
       wdt:P136 ?genrer.   # and a genre
   
   
   VALUES(?releasedDate){
       (wdt:P577)   # publication date
       (wdt:P1191)  # date of first performance
       (wdt:P1619)  # date of official opening
   }
   
      BIND(NOW() as ?now)

    FILTER (?date > "2001-01-01T00:00:00Z"^^xsd:dateTime)
    FILTER (?date < ?now) .
       

    BIND(YEAR(?date) as ?year)

   # get the label
   # ?genrer sc:name ?genre.
} GROUP BY ?genrer ?year 
HAVING (COUNT (DISTINCT ?filmr) > 50)
LIMIT 500


"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('genrer', 'http://www.wikidata.org/entity/Q645928'), ('callret-1', 'biographical film'), ('filmCount', '167')]
# [('genrer', 'http://www.wikidata.org/entity/Q130232'), ('callret-1', 'drama'), ('filmCount', '1262')]
# [('genrer', 'http://www.wikidata.org/entity/Q842256'), ('callret-1', 'musical film'), ('filmCount', '63')]
# [('genrer', 'http://www.wikidata.org/entity/Q471839'), ('callret-1', 'science fiction film'), ('filmCount', '87')]
# [('genrer', 'http://www.wikidata.org/entity/Q859369'), ('callret-1', 'comedy-drama'), ('filmCount', '92')]
# [('genrer', 'http://www.wikidata.org/entity/Q2484376'), ('callret-1', 'thriller film'), ('filmCount', '118')]
# [('genrer', 'http://www.wikidata.org/entity/Q459290'), ('callret-1', 'independent film'), ('filmCount', '53')]
# [('genrer', 'http://www.wikidata.org/entity/Q130232'), ('callret-1', 'drama'), ('filmCount', '1352')]
# [('genrer', 'http://www.wikidata.org/entity/Q859369'), ('callret-1', 'comedy-drama'), ('filmCount', '123')]
# [('genrer', 'http://www.wikidata.org/entity/Q157443'), ('callret-1', 'comedy film'), ('filmCount', '461')]
# [('genrer', 'http://www.wikidata.org/entity/Q1146335'), ('callret-1', 'teen film'), ('filmCount', '72')]
# [('genrer', 'http://www.wikidata.org/entity/Q471839'), ('callret-1', 'science fiction film'), ('filmCount', '107')]
# [('genrer', 'http://www.wikidata.org/entity/Q319221'), ('callret-1', 'adventure film'), ('filmCount', '111')]
# [('genrer', 'http://www.wikidata.org/entity/Q859369'), ('callret-1', 'comedy-drama'), ('filmCount', '167')]
# [('genrer', 'http://www.wikidata.org/entity/Q645928'), ('callret-1', 'biographical film'), ('filmCount', '162')]
# [('genrer', 'http://www.wikidata.org/entity/Q20442589'), ('callret-1', 'LGBT-related film'), ('filmCount', '113')]
# [('genrer', 'http://www.wikidata.org/entity/Q130232'), ('callret-1', 'drama'), ('filmCount', '1157')]
# [('genrer', 'http://www.wikidata.org/entity/Q369747'), ('callret-1', 'war film'), ('filmCount', '98')]
# [('genrer', 'http://www.wikidata.org/entity/Q2484376'), ('callret-1', 'thriller film'), ('filmCount', '262')]
# [('genrer', 'http://www.wikidata.org/entity/Q157394'), ('callret-1', 'fantasy film'), ('filmCount', '76')]
# [('genrer', 'http://www.wikidata.org/entity/Q1054574'), ('callret-1', 'romance film'), ('filmCount', '178')]
# [('genrer', 'http://www.wikidata.org/entity/Q1054574'), ('callret-1', 'romance film'), ('filmCount', '122')]
# [('genrer', 'http://www.wikidata.org/entity/Q842256'), ('callret-1', 'musical film'), ('filmCount', '77')]
# [('genrer', 'http://www.wikidata.org/entity/Q860626'), ('callret-1', 'romantic comedy'), ('filmCount', '194')]
# [('genrer', 'http://www.wikidata.org/entity/Q188473'), ('callret-1', 'action film'), ('filmCount', '252')]
# [('genrer', 'http://www.wikidata.org/entity/Q200092'), ('callret-1', 'horror film'), ('filmCount', '192')]
# [('genrer', 'http://www.wikidata.org/entity/Q2484376'), ('callret-1', 'thriller film'), ('filmCount', '221')]
# [('genrer', 'http://www.wikidata.org/entity/Q860626'), ('callret-1', 'romantic comedy'), ('filmCount', '136')]
# [('genrer', 'http://www.wikidata.org/entity/Q369747'), ('callret-1', 'war film'), ('filmCount', '56')]
# [('genrer', 'http://www.wikidata.org/entity/Q157443'), ('callret-1', 'comedy film'), ('filmCount', '638')]
# [('genrer', 'http://www.wikidata.org/entity/Q20442589'), ('callret-1', 'LGBT-related film'), ('filmCount', '119')]
# [('genrer', 'http://www.wikidata.org/entity/Q645928'), ('callret-1', 'biographical film'), ('filmCount', '122')]
# [('genrer', 'http://www.wikidata.org/entity/Q2484376'), ('callret-1', 'thriller film'), ('filmCount', '306')]
# [('genrer', 'http://www.wikidata.org/entity/Q52162262'), ('callret-1', 'film based on literature'), ('filmCount', '51')]
# [('genrer', 'http://www.wikidata.org/entity/Q157394'), ('callret-1', 'fantasy film'), ('filmCount', '79')]
# [('genrer', 'http://www.wikidata.org/entity/Q188473'), ('callret-1', 'action film'), ('filmCount', '243')]
# [('genrer', 'http://www.wikidata.org/entity/Q842256'), ('callret-1', 'musical film'), ('filmCount', '74')]
# [('genrer', 'http://www.wikidata.org/entity/Q645928'), ('callret-1', 'biographical film'), ('filmCount', '116')]
# [('genrer', 'http://www.wikidata.org/entity/Q200092'), ('callret-1', 'horror film'), ('filmCount', '259')]
# [('genrer', 'http://www.wikidata.org/entity/Q319221'), ('callret-1', 'adventure film'), ('filmCount', '63')]
# [('genrer', 'http://www.wikidata.org/entity/Q157394'), ('callret-1', 'fantasy film'), ('filmCount', '72')]
# [('genrer', 'http://www.wikidata.org/entity/Q188473'), ('callret-1', 'action film'), ('filmCount', '221')]
# [('genrer', 'http://www.wikidata.org/entity/Q20442589'), ('callret-1', 'LGBT-related film'), ('filmCount', '112')]
# [('genrer', 'http://www.wikidata.org/entity/Q1146335'), ('callret-1', 'teen film'), ('filmCount', '74')]
# [('genrer', 'http://www.wikidata.org/entity/Q645928'), ('callret-1', 'biographical film'), ('filmCount', '131')]
# [('genrer', 'http://www.wikidata.org/entity/Q200092'), ('callret-1', 'horror film'), ('filmCount', '280')]
# [('genrer', 'http://www.wikidata.org/entity/Q157443'), ('callret-1', 'comedy film'), ('filmCount', '436')]
# [('genrer', 'http://www.wikidata.org/entity/Q859369'), ('callret-1', 'comedy-drama'), ('filmCount', '58')]
# [('genrer', 'http://www.wikidata.org/entity/Q130232'), ('callret-1', 'drama'), ('filmCount', '1704')]
# [('genrer', 'http://www.wikidata.org/entity/Q1054574'), ('callret-1', 'romance film'), ('filmCount', '197')]
# [('genrer', 'http://www.wikidata.org/entity/Q319221'), ('callret-1', 'adventure film'), ('filmCount', '57')]
# [('genrer', 'http://www.wikidata.org/entity/Q471839'), ('callret-1', 'science fiction film'), ('filmCount', '69')]
# [('genrer', 'http://www.wikidata.org/entity/Q2484376'), ('callret-1', 'thriller film'), ('filmCount', '183')]
# [('genrer', 'http://www.wikidata.org/entity/Q200092'), ('callret-1', 'horror film'), ('filmCount', '302')]
# [('genrer', 'http://www.wikidata.org/entity/Q157394'), ('callret-1', 'fantasy film'), ('filmCount', '84')]
# [('genrer', 'http://www.wikidata.org/entity/Q860626'), ('callret-1', 'romantic comedy'), ('filmCount', '122')]
# [('genrer', 'http://www.wikidata.org/entity/Q93204'), ('callret-1', 'documentary film'), ('filmCount', '1027')]
# [('genrer', 'http://www.wikidata.org/entity/Q93204'), ('callret-1', 'documentary film'), ('filmCount', '1064')]
# [('genrer', 'http://www.wikidata.org/entity/Q20442589'), ('callret-1', 'LGBT-related film'), ('filmCount', '114')]
# [('genrer', 'http://www.wikidata.org/entity/Q1200678'), ('callret-1', 'mystery film'), ('filmCount', '65')]
# [('genrer', 'http://www.wikidata.org/entity/Q200092'), ('callret-1', 'horror film'), ('filmCount', '191')]
# [('genrer', 'http://www.wikidata.org/entity/Q93204'), ('callret-1', 'documentary film'), ('filmCount', '938')]
# [('genrer', 'http://www.wikidata.org/entity/Q842256'), ('callret-1', 'musical film'), ('filmCount', '85')]
# [('genrer', 'http://www.wikidata.org/entity/Q93204'), ('callret-1', 'documentary film'), ('filmCount', '1017')]
# [('genrer', 'http://www.wikidata.org/entity/Q93204'), ('callret-1', 'documentary film'), ('filmCount', '984')]
# [('genrer', 'http://www.wikidata.org/entity/Q645928'), ('callret-1', 'biographical film'), ('filmCount', '83')]
# [('genrer', 'http://www.wikidata.org/entity/Q130232'), ('callret-1', 'drama'), ('filmCount', '1470')]
# [('genrer', 'http://www.wikidata.org/entity/Q52207399'), ('callret-1', 'film based on a novel'), ('filmCount', '57')]
# [('genrer', 'http://www.wikidata.org/entity/Q860626'), ('callret-1', 'romantic comedy'), ('filmCount', '165')]
# [('genrer', 'http://www.wikidata.org/entity/Q842256'), ('callret-1', 'musical film'), ('filmCount', '67')]
# [('genrer', 'http://www.wikidata.org/entity/Q319221'), ('callret-1', 'adventure film'), ('filmCount', '99')]
# [('genrer', 'http://www.wikidata.org/entity/Q471839'), ('callret-1', 'science fiction film'), ('filmCount', '73')]
# [('genrer', 'http://www.wikidata.org/entity/Q860626'), ('callret-1', 'romantic comedy'), ('filmCount', '116')]
# [('genrer', 'http://www.wikidata.org/entity/Q130232'), ('callret-1', 'drama'), ('filmCount', '952')]
# [('genrer', 'http://www.wikidata.org/entity/Q1054574'), ('callret-1', 'romance film'), ('filmCount', '166')]
# [('genrer', 'http://www.wikidata.org/entity/Q157443'), ('callret-1', 'comedy film'), ('filmCount', '605')]
# [('genrer', 'http://www.wikidata.org/entity/Q959790'), ('callret-1', 'crime film'), ('filmCount', '60')]
# [('genrer', 'http://www.wikidata.org/entity/Q859369'), ('callret-1', 'comedy-drama'), ('filmCount', '114')]
# [('genrer', 'http://www.wikidata.org/entity/Q188473'), ('callret-1', 'action film'), ('filmCount', '65')]
# [('genrer', 'http://www.wikidata.org/entity/Q2484376'), ('callret-1', 'thriller film'), ('filmCount', '218')]
# [('genrer', 'http://www.wikidata.org/entity/Q645928'), ('callret-1', 'biographical film'), ('filmCount', '173')]
# [('genrer', 'http://www.wikidata.org/entity/Q2143665'), ('callret-1', "children's film"), ('filmCount', '52')]
# [('genrer', 'http://www.wikidata.org/entity/Q157394'), ('callret-1', 'fantasy film'), ('filmCount', '83')]
# [('genrer', 'http://www.wikidata.org/entity/Q2143665'), ('callret-1', "children's film"), ('filmCount', '54')]
# [('genrer', 'http://www.wikidata.org/entity/Q859369'), ('callret-1', 'comedy-drama'), ('filmCount', '128')]
# [('genrer', 'http://www.wikidata.org/entity/Q200092'), ('callret-1', 'horror film'), ('filmCount', '57')]
# [('genrer', 'http://www.wikidata.org/entity/Q369747'), ('callret-1', 'war film'), ('filmCount', '52')]
# [('genrer', 'http://www.wikidata.org/entity/Q645928'), ('callret-1', 'biographical film'), ('filmCount', '79')]
# [('genrer', 'http://www.wikidata.org/entity/Q1146335'), ('callret-1', 'teen film'), ('filmCount', '70')]
# [('genrer', 'http://www.wikidata.org/entity/Q188473'), ('callret-1', 'action film'), ('filmCount', '197')]
# [('genrer', 'http://www.wikidata.org/entity/Q52207399'), ('callret-1', 'film based on a novel'), ('filmCount', '55')]
# [('genrer', 'http://www.wikidata.org/entity/Q1146335'), ('callret-1', 'teen film'), ('filmCount', '56')]
# [('genrer', 'http://www.wikidata.org/entity/Q859369'), ('callret-1', 'comedy-drama'), ('filmCount', '201')]
# [('genrer', 'http://www.wikidata.org/entity/Q959790'), ('callret-1', 'crime film'), ('filmCount', '110')]
# [('genrer', 'http://www.wikidata.org/entity/Q188473'), ('callret-1', 'action film'), ('filmCount', '72')]
# [('genrer', 'http://www.wikidata.org/entity/Q471839'), ('callret-1', 'science fiction film'), ('filmCount', '112')]
# [('genrer', 'http://www.wikidata.org/entity/Q471839'), ('callret-1', 'science fiction film'), ('filmCount', '82')]
# [('genrer', 'http://www.wikidata.org/entity/Q157443'), ('callret-1', 'comedy film'), ('filmCount', '391')]
# [('genrer', 'http://www.wikidata.org/entity/Q157394'), ('callret-1', 'fantasy film'), ('filmCount', '64')]
# [('genrer', 'http://www.wikidata.org/entity/Q157443'), ('callret-1', 'comedy film'), ('filmCount', '524')]
# [('genrer', 'http://www.wikidata.org/entity/Q860626'), ('callret-1', 'romantic comedy'), ('filmCount', '154')]
# [('genrer', 'http://www.wikidata.org/entity/Q2484376'), ('callret-1', 'thriller film'), ('filmCount', '121')]
# [('genrer', 'http://www.wikidata.org/entity/Q959790'), ('callret-1', 'crime film'), ('filmCount', '143')]
# [('genrer', 'http://www.wikidata.org/entity/Q185529'), ('callret-1', 'pornographic film'), ('filmCount', '52')]
# [('genrer', 'http://www.wikidata.org/entity/Q645928'), ('callret-1', 'biographical film'), ('filmCount', '388')]
# [('genrer', 'http://www.wikidata.org/entity/Q842256'), ('callret-1', 'musical film'), ('filmCount', '61')]
# [('genrer', 'http://www.wikidata.org/entity/Q157394'), ('callret-1', 'fantasy film'), ('filmCount', '80')]
# [('genrer', 'http://www.wikidata.org/entity/Q1339864'), ('callret-1', 'sport film'), ('filmCount', '143')]
# [('genrer', 'http://www.wikidata.org/entity/Q93204'), ('callret-1', 'documentary film'), ('filmCount', '1030')]
# [('genrer', 'http://www.wikidata.org/entity/Q93204'), ('callret-1', 'documentary film'), ('filmCount', '939')]
# [('genrer', 'http://www.wikidata.org/entity/Q93204'), ('callret-1', 'documentary film'), ('filmCount', '867')]
# [('genrer', 'http://www.wikidata.org/entity/Q1054574'), ('callret-1', 'romance film'), ('filmCount', '184')]
# [('genrer', 'http://www.wikidata.org/entity/Q842256'), ('callret-1', 'musical film'), ('filmCount', '72')]
# [('genrer', 'http://www.wikidata.org/entity/Q93204'), ('callret-1', 'documentary film'), ('filmCount', '760')]
# [('genrer', 'http://www.wikidata.org/entity/Q93204'), ('callret-1', 'documentary film'), ('filmCount', '606')]
# [('genrer', 'http://www.wikidata.org/entity/Q645928'), ('callret-1', 'biographical film'), ('filmCount', '94')]
# [('genrer', 'http://www.wikidata.org/entity/Q20442589'), ('callret-1', 'LGBT-related film'), ('filmCount', '144')]
# [('genrer', 'http://www.wikidata.org/entity/Q1200678'), ('callret-1', 'mystery film'), ('filmCount', '82')]
# [('genrer', 'http://www.wikidata.org/entity/Q860626'), ('callret-1', 'romantic comedy'), ('filmCount', '160')]
# [('genrer', 'http://www.wikidata.org/entity/Q959790'), ('callret-1', 'crime film'), ('filmCount', '168')]
# [('genrer', 'http://www.wikidata.org/entity/Q319221'), ('callret-1', 'adventure film'), ('filmCount', '52')]
# [('genrer', 'http://www.wikidata.org/entity/Q2484376'), ('callret-1', 'thriller film'), ('filmCount', '161')]
# [('genrer', 'http://www.wikidata.org/entity/Q130232'), ('callret-1', 'drama'), ('filmCount', '670')]
# [('genrer', 'http://www.wikidata.org/entity/Q157443'), ('callret-1', 'comedy film'), ('filmCount', '543')]
# [('genrer', 'http://www.wikidata.org/entity/Q52207399'), ('callret-1', 'film based on a novel'), ('filmCount', '52')]
# [('genrer', 'http://www.wikidata.org/entity/Q645928'), ('callret-1', 'biographical film'), ('filmCount', '74')]
# [('genrer', 'http://www.wikidata.org/entity/Q645928'), ('callret-1', 'biographical film'), ('filmCount', '166')]
# [('genrer', 'http://www.wikidata.org/entity/Q860626'), ('callret-1', 'romantic comedy'), ('filmCount', '132')]
# [('genrer', 'http://www.wikidata.org/entity/Q157394'), ('callret-1', 'fantasy film'), ('filmCount', '85')]
# [('genrer', 'http://www.wikidata.org/entity/Q188473'), ('callret-1', 'action film'), ('filmCount', '185')]
# [('genrer', 'http://www.wikidata.org/entity/Q130232'), ('callret-1', 'drama'), ('filmCount', '1354')]
# [('genrer', 'http://www.wikidata.org/entity/Q1146335'), ('callret-1', 'teen film'), ('filmCount', '60')]
# [('genrer', 'http://www.wikidata.org/entity/Q369747'), ('callret-1', 'war film'), ('filmCount', '51')]
# [('genrer', 'http://www.wikidata.org/entity/Q645928'), ('callret-1', 'biographical film'), ('filmCount', '92')]
# [('genrer', 'http://www.wikidata.org/entity/Q959790'), ('callret-1', 'crime film'), ('filmCount', '144')]
# [('genrer', 'http://www.wikidata.org/entity/Q20442589'), ('callret-1', 'LGBT-related film'), ('filmCount', '142')]
# [('genrer', 'http://www.wikidata.org/entity/Q842256'), ('callret-1', 'musical film'), ('filmCount', '80')]
# [('genrer', 'http://www.wikidata.org/entity/Q20442589'), ('callret-1', 'LGBT-related film'), ('filmCount', '133')]
# [('genrer', 'http://www.wikidata.org/entity/Q1054574'), ('callret-1', 'romance film'), ('filmCount', '218')]
# [('genrer', 'http://www.wikidata.org/entity/Q2484376'), ('callret-1', 'thriller film'), ('filmCount', '316')]
# [('genrer', 'http://www.wikidata.org/entity/Q842256'), ('callret-1', 'musical film'), ('filmCount', '83')]
# [('genrer', 'http://www.wikidata.org/entity/Q130232'), ('callret-1', 'drama'), ('filmCount', '1254')]
# [('genrer', 'http://www.wikidata.org/entity/Q157443'), ('callret-1', 'comedy film'), ('filmCount', '160')]
# [('genrer', 'http://www.wikidata.org/entity/Q188473'), ('callret-1', 'action film'), ('filmCount', '204')]
# [('genrer', 'http://www.wikidata.org/entity/Q471839'), ('callret-1', 'science fiction film'), ('filmCount', '67')]
# [('genrer', 'http://www.wikidata.org/entity/Q200092'), ('callret-1', 'horror film'), ('filmCount', '133')]
# [('genrer', 'http://www.wikidata.org/entity/Q20442589'), ('callret-1', 'LGBT-related film'), ('filmCount', '122')]
# [('genrer', 'http://www.wikidata.org/entity/Q157443'), ('callret-1', 'comedy film'), ('filmCount', '651')]
# [('genrer', 'http://www.wikidata.org/entity/Q959790'), ('callret-1', 'crime film'), ('filmCount', '127')]
# [('genrer', 'http://www.wikidata.org/entity/Q860626'), ('callret-1', 'romantic comedy'), ('filmCount', '143')]
# [('genrer', 'http://www.wikidata.org/entity/Q645928'), ('callret-1', 'biographical film'), ('filmCount', '71')]
# [('genrer', 'http://www.wikidata.org/entity/Q188473'), ('callret-1', 'action film'), ('filmCount', '260')]
# [('genrer', 'http://www.wikidata.org/entity/Q471839'), ('callret-1', 'science fiction film'), ('filmCount', '78')]
# [('genrer', 'http://www.wikidata.org/entity/Q860626'), ('callret-1', 'romantic comedy'), ('filmCount', '163')]
# [('genrer', 'http://www.wikidata.org/entity/Q859369'), ('callret-1', 'comedy-drama'), ('filmCount', '138')]
# [('genrer', 'http://www.wikidata.org/entity/Q1200678'), ('callret-1', 'mystery film'), ('filmCount', '69')]
# [('genrer', 'http://www.wikidata.org/entity/Q645928'), ('callret-1', 'biographical film'), ('filmCount', '124')]
# [('genrer', 'http://www.wikidata.org/entity/Q188473'), ('callret-1', 'action film'), ('filmCount', '237')]
# [('genrer', 'http://www.wikidata.org/entity/Q319221'), ('callret-1', 'adventure film'), ('filmCount', '56')]
# [('genrer', 'http://www.wikidata.org/entity/Q200092'), ('callret-1', 'horror film'), ('filmCount', '218')]
# [('genrer', 'http://www.wikidata.org/entity/Q959790'), ('callret-1', 'crime film'), ('filmCount', '120')]
# [('genrer', 'http://www.wikidata.org/entity/Q2143665'), ('callret-1', "children's film"), ('filmCount', '58')]
# [('genrer', 'http://www.wikidata.org/entity/Q859369'), ('callret-1', 'comedy-drama'), ('filmCount', '109')]
# [('genrer', 'http://www.wikidata.org/entity/Q471839'), ('callret-1', 'science fiction film'), ('filmCount', '103')]
# [('genrer', 'http://www.wikidata.org/entity/Q2143665'), ('callret-1', "children's film"), ('filmCount', '60')]
# [('genrer', 'http://www.wikidata.org/entity/Q2143665'), ('callret-1', "children's film"), ('filmCount', '51')]
# [('genrer', 'http://www.wikidata.org/entity/Q157443'), ('callret-1', 'comedy film'), ('filmCount', '530')]
# [('genrer', 'http://www.wikidata.org/entity/Q859369'), ('callret-1', 'comedy-drama'), ('filmCount', '158')]
# [('genrer', 'http://www.wikidata.org/entity/Q860626'), ('callret-1', 'romantic comedy'), ('filmCount', '190')]
# [('genrer', 'http://www.wikidata.org/entity/Q188473'), ('callret-1', 'action film'), ('filmCount', '269')]
# [('genrer', 'http://www.wikidata.org/entity/Q93204'), ('callret-1', 'documentary film'), ('filmCount', '219')]
# [('genrer', 'http://www.wikidata.org/entity/Q17013749'), ('callret-1', 'historical film'), ('filmCount', '55')]
# [('genrer', 'http://www.wikidata.org/entity/Q93204'), ('callret-1', 'documentary film'), ('filmCount', '557')]
# [('genrer', 'http://www.wikidata.org/entity/Q93204'), ('callret-1', 'documentary film'), ('filmCount', '840')]
# [('genrer', 'http://www.wikidata.org/entity/Q93204'), ('callret-1', 'documentary film'), ('filmCount', '933')]
# [('genrer', 'http://www.wikidata.org/entity/Q369747'), ('callret-1', 'war film'), ('filmCount', '57')]
# [('genrer', 'http://www.wikidata.org/entity/Q17013749'), ('callret-1', 'historical film'), ('filmCount', '78')]
# [('genrer', 'http://www.wikidata.org/entity/Q93204'), ('callret-1', 'documentary film'), ('filmCount', '1043')]
# [('genrer', 'http://www.wikidata.org/entity/Q471839'), ('callret-1', 'science fiction film'), ('filmCount', '57')]
# [('genrer', 'http://www.wikidata.org/entity/Q959790'), ('callret-1', 'crime film'), ('filmCount', '111')]
# [('genrer', 'http://www.wikidata.org/entity/Q200092'), ('callret-1', 'horror film'), ('filmCount', '275')]
# [('genrer', 'http://www.wikidata.org/entity/Q130232'), ('callret-1', 'drama'), ('filmCount', '1622')]
# [('genrer', 'http://www.wikidata.org/entity/Q2484376'), ('callret-1', 'thriller film'), ('filmCount', '189')]
# [('genrer', 'http://www.wikidata.org/entity/Q1054574'), ('callret-1', 'romance film'), ('filmCount', '163')]
# [('genrer', 'http://www.wikidata.org/entity/Q319221'), ('callret-1', 'adventure film'), ('filmCount', '55')]
# [('genrer', 'http://www.wikidata.org/entity/Q200092'), ('callret-1', 'horror film'), ('filmCount', '247')]
# [('genrer', 'http://www.wikidata.org/entity/Q157394'), ('callret-1', 'fantasy film'), ('filmCount', '77')]
# [('genrer', 'http://www.wikidata.org/entity/Q959790'), ('callret-1', 'crime film'), ('filmCount', '81')]
# [('genrer', 'http://www.wikidata.org/entity/Q157443'), ('callret-1', 'comedy film'), ('filmCount', '673')]
# [('genrer', 'http://www.wikidata.org/entity/Q130232'), ('callret-1', 'drama'), ('filmCount', '1507')]
# [('genrer', 'http://www.wikidata.org/entity/Q200092'), ('callret-1', 'horror film'), ('filmCount', '281')]
# [('genrer', 'http://www.wikidata.org/entity/Q20442589'), ('callret-1', 'LGBT-related film'), ('filmCount', '150')]
# [('genrer', 'http://www.wikidata.org/entity/Q645928'), ('callret-1', 'biographical film'), ('filmCount', '85')]
# [('genrer', 'http://www.wikidata.org/entity/Q860626'), ('callret-1', 'romantic comedy'), ('filmCount', '142')]
# [('genrer', 'http://www.wikidata.org/entity/Q2484376'), ('callret-1', 'thriller film'), ('filmCount', '265')]
# [('genrer', 'http://www.wikidata.org/entity/Q130232'), ('callret-1', 'drama'), ('filmCount', '1042')]
# [('genrer', 'http://www.wikidata.org/entity/Q1054574'), ('callret-1', 'romance film'), ('filmCount', '225')]
# [('genrer', 'http://www.wikidata.org/entity/Q200092'), ('callret-1', 'horror film'), ('filmCount', '161')]
# [('genrer', 'http://www.wikidata.org/entity/Q859369'), ('callret-1', 'comedy-drama'), ('filmCount', '122')]
# [('genrer', 'http://www.wikidata.org/entity/Q959790'), ('callret-1', 'crime film'), ('filmCount', '88')]
# [('genrer', 'http://www.wikidata.org/entity/Q188473'), ('callret-1', 'action film'), ('filmCount', '266')]
# [('genrer', 'http://www.wikidata.org/entity/Q1200678'), ('callret-1', 'mystery film'), ('filmCount', '70')]
# [('genrer', 'http://www.wikidata.org/entity/Q52207399'), ('callret-1', 'film based on a novel'), ('filmCount', '56')]
# [('genrer', 'http://www.wikidata.org/entity/Q2484376'), ('callret-1', 'thriller film'), ('filmCount', '119')]
# [('genrer', 'http://www.wikidata.org/entity/Q959790'), ('callret-1', 'crime film'), ('filmCount', '106')]
# [('genrer', 'http://www.wikidata.org/entity/Q157394'), ('callret-1', 'fantasy film'), ('filmCount', '68')]
# [('genrer', 'http://www.wikidata.org/entity/Q157443'), ('callret-1', 'comedy film'), ('filmCount', '563')]
# [('genrer', 'http://www.wikidata.org/entity/Q130232'), ('callret-1', 'drama'), ('filmCount', '287')]
# [('genrer', 'http://www.wikidata.org/entity/Q20442589'), ('callret-1', 'LGBT-related film'), ('filmCount', '132')]
# [('genrer', 'http://www.wikidata.org/entity/Q959790'), ('callret-1', 'crime film'), ('filmCount', '132')]
# [('genrer', 'http://www.wikidata.org/entity/Q93204'), ('callret-1', 'documentary film'), ('filmCount', '3429')]
# [('genrer', 'http://www.wikidata.org/entity/Q319221'), ('callret-1', 'adventure film'), ('filmCount', '95')]
# [('genrer', 'http://www.wikidata.org/entity/Q93204'), ('callret-1', 'documentary film'), ('filmCount', '1098')]
# [('genrer', 'http://www.wikidata.org/entity/Q93204'), ('callret-1', 'documentary film'), ('filmCount', '1083')]
# [('genrer', 'http://www.wikidata.org/entity/Q471839'), ('callret-1', 'science fiction film'), ('filmCount', '64')]
# [('genrer', 'http://www.wikidata.org/entity/Q959790'), ('callret-1', 'crime film'), ('filmCount', '116')]
# [('genrer', 'http://www.wikidata.org/entity/Q2484376'), ('callret-1', 'thriller film'), ('filmCount', '154')]
# [('genrer', 'http://www.wikidata.org/entity/Q1054574'), ('callret-1', 'romance film'), ('filmCount', '162')]
# [('genrer', 'http://www.wikidata.org/entity/Q859369'), ('callret-1', 'comedy-drama'), ('filmCount', '103')]
# [('genrer', 'http://www.wikidata.org/entity/Q188473'), ('callret-1', 'action film'), ('filmCount', '250')]
# [('genrer', 'http://www.wikidata.org/entity/Q959790'), ('callret-1', 'crime film'), ('filmCount', '167')]
# [('genrer', 'http://www.wikidata.org/entity/Q645928'), ('callret-1', 'biographical film'), ('filmCount', '57')]
# [('genrer', 'http://www.wikidata.org/entity/Q1054574'), ('callret-1', 'romance film'), ('filmCount', '142')]
# [('genrer', 'http://www.wikidata.org/entity/Q859369'), ('callret-1', 'comedy-drama'), ('filmCount', '112')]
# [('genrer', 'http://www.wikidata.org/entity/Q471839'), ('callret-1', 'science fiction film'), ('filmCount', '86')]
# [('genrer', 'http://www.wikidata.org/entity/Q471839'), ('callret-1', 'science fiction film'), ('filmCount', '93')]
# [('genrer', 'http://www.wikidata.org/entity/Q157443'), ('callret-1', 'comedy film'), ('filmCount', '718')]
# [('genrer', 'http://www.wikidata.org/entity/Q20442589'), ('callret-1', 'LGBT-related film'), ('filmCount', '146')]
# [('genrer', 'http://www.wikidata.org/entity/Q188473'), ('callret-1', 'action film'), ('filmCount', '122')]
# [('genrer', 'http://www.wikidata.org/entity/Q859369'), ('callret-1', 'comedy-drama'), ('filmCount', '149')]
# [('genrer', 'http://www.wikidata.org/entity/Q1200678'), ('callret-1', 'mystery film'), ('filmCount', '52')]
# [('genrer', 'http://www.wikidata.org/entity/Q157443'), ('callret-1', 'comedy film'), ('filmCount', '155')]
# [('genrer', 'http://www.wikidata.org/entity/Q860626'), ('callret-1', 'romantic comedy'), ('filmCount', '145')]
# [('genrer', 'http://www.wikidata.org/entity/Q471839'), ('callret-1', 'science fiction film'), ('filmCount', '89')]
# [('genrer', 'http://www.wikidata.org/entity/Q959790'), ('callret-1', 'crime film'), ('filmCount', '112')]
# [('genrer', 'http://www.wikidata.org/entity/Q130232'), ('callret-1', 'drama'), ('filmCount', '337')]
# [('genrer', 'http://www.wikidata.org/entity/Q1054574'), ('callret-1', 'romance film'), ('filmCount', '209')]
# [('genrer', 'http://www.wikidata.org/entity/Q860626'), ('callret-1', 'romantic comedy'), ('filmCount', '155')]
# [('genrer', 'http://www.wikidata.org/entity/Q130232'), ('callret-1', 'drama'), ('filmCount', '1406')]
# [('genrer', 'http://www.wikidata.org/entity/Q2484376'), ('callret-1', 'thriller film'), ('filmCount', '87')]
# [('genrer', 'http://www.wikidata.org/entity/Q157394'), ('callret-1', 'fantasy film'), ('filmCount', '67')]
# [('genrer', 'http://www.wikidata.org/entity/Q471839'), ('callret-1', 'science fiction film'), ('filmCount', '52')]
# [('genrer', 'http://www.wikidata.org/entity/Q157443'), ('callret-1', 'comedy film'), ('filmCount', '520')]
# [('genrer', 'http://www.wikidata.org/entity/Q369747'), ('callret-1', 'war film'), ('filmCount', '53')]
# [('genrer', 'http://www.wikidata.org/entity/Q959790'), ('callret-1', 'crime film'), ('filmCount', '128')]
# [('genrer', 'http://www.wikidata.org/entity/Q130232'), ('callret-1', 'drama'), ('filmCount', '1476')]
# [('genrer', 'http://www.wikidata.org/entity/Q130232'), ('callret-1', 'drama'), ('filmCount', '1267')]
# [('genrer', 'http://www.wikidata.org/entity/Q1054574'), ('callret-1', 'romance film'), ('filmCount', '181')]
# [('genrer', 'http://www.wikidata.org/entity/Q20442589'), ('callret-1', 'LGBT-related film'), ('filmCount', '91')]
# [('genrer', 'http://www.wikidata.org/entity/Q842256'), ('callret-1', 'musical film'), ('filmCount', '65')]
# [('genrer', 'http://www.wikidata.org/entity/Q188473'), ('callret-1', 'action film'), ('filmCount', '176')]
# [('genrer', 'http://www.wikidata.org/entity/Q842256'), ('callret-1', 'musical film'), ('filmCount', '62')]
# [('genrer', 'http://www.wikidata.org/entity/Q157394'), ('callret-1', 'fantasy film'), ('filmCount', '78')]
# [('genrer', 'http://www.wikidata.org/entity/Q860626'), ('callret-1', 'romantic comedy'), ('filmCount', '128')]
# [('genrer', 'http://www.wikidata.org/entity/Q157443'), ('callret-1', 'comedy film'), ('filmCount', '619')]
# [('genrer', 'http://www.wikidata.org/entity/Q319221'), ('callret-1', 'adventure film'), ('filmCount', '90')]
# [('genrer', 'http://www.wikidata.org/entity/Q1146335'), ('callret-1', 'teen film'), ('filmCount', '57')]
# [('genrer', 'http://www.wikidata.org/entity/Q2484376'), ('callret-1', 'thriller film'), ('filmCount', '178')]
# [('genrer', 'http://www.wikidata.org/entity/Q1054574'), ('callret-1', 'romance film'), ('filmCount', '203')]
# [('genrer', 'http://www.wikidata.org/entity/Q185529'), ('callret-1', 'pornographic film'), ('filmCount', '53')]
# [('genrer', 'http://www.wikidata.org/entity/Q959790'), ('callret-1', 'crime film'), ('filmCount', '96')]
# [('genrer', 'http://www.wikidata.org/entity/Q157443'), ('callret-1', 'comedy film'), ('filmCount', '282')]
# [('genrer', 'http://www.wikidata.org/entity/Q188473'), ('callret-1', 'action film'), ('filmCount', '213')]
# [('genrer', 'http://www.wikidata.org/entity/Q20442589'), ('callret-1', 'LGBT-related film'), ('filmCount', '116')]
# [('genrer', 'http://www.wikidata.org/entity/Q471839'), ('callret-1', 'science fiction film'), ('filmCount', '62')]
# [('genrer', 'http://www.wikidata.org/entity/Q1200678'), ('callret-1', 'mystery film'), ('filmCount', '72')]
# [('genrer', 'http://www.wikidata.org/entity/Q842256'), ('callret-1', 'musical film'), ('filmCount', '52')]
# [('genrer', 'http://www.wikidata.org/entity/Q200092'), ('callret-1', 'horror film'), ('filmCount', '260')]
# [('genrer', 'http://www.wikidata.org/entity/Q959790'), ('callret-1', 'crime film'), ('filmCount', '105')]
# [('genrer', 'http://www.wikidata.org/entity/Q200092'), ('callret-1', 'horror film'), ('filmCount', '268')]
# [('genrer', 'http://www.wikidata.org/entity/Q157443'), ('callret-1', 'comedy film'), ('filmCount', '528')]
# [('genrer', 'http://www.wikidata.org/entity/Q1200678'), ('callret-1', 'mystery film'), ('filmCount', '54')]
# [('genrer', 'http://www.wikidata.org/entity/Q157394'), ('callret-1', 'fantasy film'), ('filmCount', '53')]
# [('genrer', 'http://www.wikidata.org/entity/Q859369'), ('callret-1', 'comedy-drama'), ('filmCount', '131')]
# [('genrer', 'http://www.wikidata.org/entity/Q319221'), ('callret-1', 'adventure film'), ('filmCount', '74')]
# [('genrer', 'http://www.wikidata.org/entity/Q2484376'), ('callret-1', 'thriller film'), ('filmCount', '137')]
# [('genrer', 'http://www.wikidata.org/entity/Q200092'), ('callret-1', 'horror film'), ('filmCount', '298')]
# [('genrer', 'http://www.wikidata.org/entity/Q859369'), ('callret-1', 'comedy-drama'), ('filmCount', '121')]
# [('genrer', 'http://www.wikidata.org/entity/Q200092'), ('callret-1', 'horror film'), ('filmCount', '246')]
# [('genrer', 'http://www.wikidata.org/entity/Q130232'), ('callret-1', 'drama'), ('filmCount', '1566')]
# [('genrer', 'http://www.wikidata.org/entity/Q471839'), ('callret-1', 'science fiction film'), ('filmCount', '99')]
# [('genrer', 'http://www.wikidata.org/entity/Q157394'), ('callret-1', 'fantasy film'), ('filmCount', '55')]
# [('genrer', 'http://www.wikidata.org/entity/Q859369'), ('callret-1', 'comedy-drama'), ('filmCount', '141')]
# [('genrer', 'http://www.wikidata.org/entity/Q1054574'), ('callret-1', 'romance film'), ('filmCount', '151')]
# [('genrer', 'http://www.wikidata.org/entity/Q17013749'), ('callret-1', 'historical film'), ('filmCount', '83')]
# [('genrer', 'http://www.wikidata.org/entity/Q2484376'), ('callret-1', 'thriller film'), ('filmCount', '305')]
# [('genrer', 'http://www.wikidata.org/entity/Q20442589'), ('callret-1', 'LGBT-related film'), ('filmCount', '126')]
# [('genrer', 'http://www.wikidata.org/entity/Q200092'), ('callret-1', 'horror film'), ('filmCount', '305')]
# [('genrer', 'http://www.wikidata.org/entity/Q17013749'), ('callret-1', 'historical film'), ('filmCount', '61')]
# [('genrer', 'http://www.wikidata.org/entity/Q17013749'), ('callret-1', 'historical film'), ('filmCount', '229')]
# [('genrer', 'http://www.wikidata.org/entity/Q130232'), ('callret-1', 'drama'), ('filmCount', '1094')]
# [('genrer', 'http://www.wikidata.org/entity/Q188473'), ('callret-1', 'action film'), ('filmCount', '203')]
# [('genrer', 'http://www.wikidata.org/entity/Q20442589'), ('callret-1', 'LGBT-related film'), ('filmCount', '110')]
# [('genrer', 'http://www.wikidata.org/entity/Q157443'), ('callret-1', 'comedy film'), ('filmCount', '680')]
# [('genrer', 'http://www.wikidata.org/entity/Q130232'), ('callret-1', 'drama'), ('filmCount', '1477')]
# [('genrer', 'http://www.wikidata.org/entity/Q200092'), ('callret-1', 'horror film'), ('filmCount', '132')]
# [('genrer', 'http://www.wikidata.org/entity/Q188473'), ('callret-1', 'action film'), ('filmCount', '224')]
# [('genrer', 'http://www.wikidata.org/entity/Q1054574'), ('callret-1', 'romance film'), ('filmCount', '226')]
# [('genrer', 'http://www.wikidata.org/entity/Q130232'), ('callret-1', 'drama'), ('filmCount', '919')]
# [('genrer', 'http://www.wikidata.org/entity/Q2143665'), ('callret-1', "children's film"), ('filmCount', '56')]
# [('genrer', 'http://www.wikidata.org/entity/Q157394'), ('callret-1', 'fantasy film'), ('filmCount', '69')]
# [('genrer', 'http://www.wikidata.org/entity/Q20442589'), ('callret-1', 'LGBT-related film'), ('filmCount', '95')]
# [('genrer', 'http://www.wikidata.org/entity/Q319221'), ('callret-1', 'adventure film'), ('filmCount', '166')]
# [('genrer', 'http://www.wikidata.org/entity/Q188473'), ('callret-1', 'action film'), ('filmCount', '248')]
# [('genrer', 'http://www.wikidata.org/entity/Q2484376'), ('callret-1', 'thriller film'), ('filmCount', '199')]
# [('genrer', 'http://www.wikidata.org/entity/Q93204'), ('callret-1', 'documentary film'), ('filmCount', '554')]
# [('genrer', 'http://www.wikidata.org/entity/Q93204'), ('callret-1', 'documentary film'), ('filmCount', '469')]
# [('genrer', 'http://www.wikidata.org/entity/Q93204'), ('callret-1', 'documentary film'), ('filmCount', '68')]
# [('genrer', 'http://www.wikidata.org/entity/Q157443'), ('callret-1', 'comedy film'), ('filmCount', '421')]
# [('genrer', 'http://www.wikidata.org/entity/Q20442589'), ('callret-1', 'LGBT-related film'), ('filmCount', '118')]
# [('genrer', 'http://www.wikidata.org/entity/Q1146335'), ('callret-1', 'teen film'), ('filmCount', '85')]
# [('genrer', 'http://www.wikidata.org/entity/Q1054574'), ('callret-1', 'romance film'), ('filmCount', '175')]
# [('genrer', 'http://www.wikidata.org/entity/Q842256'), ('callret-1', 'musical film'), ('filmCount', '70')]
# [('genrer', 'http://www.wikidata.org/entity/Q859369'), ('callret-1', 'comedy-drama'), ('filmCount', '116')]
# [('genrer', 'http://www.wikidata.org/entity/Q860626'), ('callret-1', 'romantic comedy'), ('filmCount', '212')]
# [('genrer', 'http://www.wikidata.org/entity/Q319221'), ('callret-1', 'adventure film'), ('filmCount', '81')]
# [('genrer', 'http://www.wikidata.org/entity/Q157394'), ('callret-1', 'fantasy film'), ('filmCount', '61')]
# [('genrer', 'http://www.wikidata.org/entity/Q1146335'), ('callret-1', 'teen film'), ('filmCount', '51')]
# [('genrer', 'http://www.wikidata.org/entity/Q157443'), ('callret-1', 'comedy film'), ('filmCount', '622')]
# [('genrer', 'http://www.wikidata.org/entity/Q1054574'), ('callret-1', 'romance film'), ('filmCount', '80')]
# [('genrer', 'http://www.wikidata.org/entity/Q1361932'), ('callret-1', 'family film'), ('filmCount', '86')]
# [('genrer', 'http://www.wikidata.org/entity/Q860626'), ('callret-1', 'romantic comedy'), ('filmCount', '90')]
# [('genrer', 'http://www.wikidata.org/entity/Q188473'), ('callret-1', 'action film'), ('filmCount', '267')]
# [('genrer', 'http://www.wikidata.org/entity/Q20442589'), ('callret-1', 'LGBT-related film'), ('filmCount', '96')]
# [('genrer', 'http://www.wikidata.org/entity/Q1054574'), ('callret-1', 'romance film'), ('filmCount', '154')]
# 325

# %%
queryString = """
SELECT DISTINCT ?genrer SAMPLE(?genreLabel) (SUM(?filmCount) as ?totalFilmCount)
WHERE {
{
    SELECT DISTINCT ?genrer ?year (SAMPLE(?genre) as ?genreLabel) (COUNT(DISTINCT ?filmr) as ?filmCount)
    WHERE {

       # ?filmr wdt:P31 wd:Q11424;  # generic film
           # ?releaseDate ?date; # with a publication date
           wdt:P136 ?genrer.   # and a genre


       VALUES(?releasedDate){
           (wdt:P577)   # publication date
           (wdt:P1191)  # date of first performance
           (wdt:P1619)  # date of official opening
       }

          BIND(NOW() as ?now)

        FILTER (?date > "2001-01-01T00:00:00Z"^^xsd:dateTime)
        FILTER (?date < ?now) .


        BIND(YEAR(?date) as ?year)

       # get the label
       # ?genrer sc:name ?genre.
    } GROUP BY ?genrer ?year 
    HAVING (COUNT (DISTINCT ?filmr) > 50)
}

} GROUP BY ?genrer
LIMIT 500

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('genrer', 'http://www.wikidata.org/entity/Q471839'), ('callret-1', 'science fiction film'), ('totalFilmCount', '1466')]
# [('genrer', 'http://www.wikidata.org/entity/Q93204'), ('callret-1', 'documentary film'), ('totalFilmCount', '19525')]
# [('genrer', 'http://www.wikidata.org/entity/Q959790'), ('callret-1', 'crime film'), ('totalFilmCount', '2241')]
# [('genrer', 'http://www.wikidata.org/entity/Q369747'), ('callret-1', 'war film'), ('totalFilmCount', '418')]
# [('genrer', 'http://www.wikidata.org/entity/Q1339864'), ('callret-1', 'sport film'), ('totalFilmCount', '143')]
# [('genrer', 'http://www.wikidata.org/entity/Q188473'), ('callret-1', 'action film'), ('totalFilmCount', '4417')]
# [('genrer', 'http://www.wikidata.org/entity/Q1146335'), ('callret-1', 'teen film'), ('totalFilmCount', '581')]
# [('genrer', 'http://www.wikidata.org/entity/Q157394'), ('callret-1', 'fantasy film'), ('totalFilmCount', '1310')]
# [('genrer', 'http://www.wikidata.org/entity/Q130232'), ('callret-1', 'drama'), ('totalFilmCount', '25175')]
# [('genrer', 'http://www.wikidata.org/entity/Q1361932'), ('callret-1', 'family film'), ('totalFilmCount', '86')]
# [('genrer', 'http://www.wikidata.org/entity/Q17013749'), ('callret-1', 'historical film'), ('totalFilmCount', '506')]
# [('genrer', 'http://www.wikidata.org/entity/Q2484376'), ('callret-1', 'thriller film'), ('totalFilmCount', '3965')]
# [('genrer', 'http://www.wikidata.org/entity/Q20442589'), ('callret-1', 'LGBT-related film'), ('totalFilmCount', '2179')]
# [('genrer', 'http://www.wikidata.org/entity/Q859369'), ('callret-1', 'comedy-drama'), ('totalFilmCount', '2406')]
# [('genrer', 'http://www.wikidata.org/entity/Q200092'), ('callret-1', 'horror film'), ('totalFilmCount', '4485')]
# [('genrer', 'http://www.wikidata.org/entity/Q157443'), ('callret-1', 'comedy film'), ('totalFilmCount', '10720')]
# [('genrer', 'http://www.wikidata.org/entity/Q52207399'), ('callret-1', 'film based on a novel'), ('totalFilmCount', '275')]
# [('genrer', 'http://www.wikidata.org/entity/Q319221'), ('callret-1', 'adventure film'), ('totalFilmCount', '999')]
# [('genrer', 'http://www.wikidata.org/entity/Q842256'), ('callret-1', 'musical film'), ('totalFilmCount', '1271')]
# [('genrer', 'http://www.wikidata.org/entity/Q860626'), ('callret-1', 'romantic comedy'), ('totalFilmCount', '2712')]
# [('genrer', 'http://www.wikidata.org/entity/Q645928'), ('callret-1', 'biographical film'), ('totalFilmCount', '2258')]
# [('genrer', 'http://www.wikidata.org/entity/Q1200678'), ('callret-1', 'mystery film'), ('totalFilmCount', '516')]
# [('genrer', 'http://www.wikidata.org/entity/Q185529'), ('callret-1', 'pornographic film'), ('totalFilmCount', '105')]
# [('genrer', 'http://www.wikidata.org/entity/Q1054574'), ('callret-1', 'romance film'), ('totalFilmCount', '3320')]
# [('genrer', 'http://www.wikidata.org/entity/Q52162262'), ('callret-1', 'film based on literature'), ('totalFilmCount', '51')]
# [('genrer', 'http://www.wikidata.org/entity/Q459290'), ('callret-1', 'independent film'), ('totalFilmCount', '106')]
# [('genrer', 'http://www.wikidata.org/entity/Q2143665'), ('callret-1', "children's film"), ('totalFilmCount', '497')]
# 27

# %%
queryString = """
SELECT DISTINCT ?genrer SAMPLE(?genreLabel) (SUM(?filmCount) as ?totalFilmCount)
(COUNT(DISTINCT ?year) AS ?numberOfYearsPassed)
WHERE {
{
    SELECT DISTINCT ?genrer ?year (SAMPLE(?genre) as ?genreLabel) (COUNT(DISTINCT ?filmr) as ?filmCount)
    WHERE {

       # ?filmr wdt:P31 wd:Q11424;  # generic film
           # ?releaseDate ?date; # with a publication date
           wdt:P136 ?genrer.   # and a genre


       VALUES(?releasedDate){
           (wdt:P577)   # publication date
           (wdt:P1191)  # date of first performance
           (wdt:P1619)  # date of official opening
       }

          BIND(NOW() as ?now)

        FILTER (?date > "2001-01-01T00:00:00Z"^^xsd:dateTime)
        FILTER (?date < ?now) .


        BIND(YEAR(?date) as ?year)

       # get the label
       # ?genrer sc:name ?genre.
    } GROUP BY ?genrer ?year 
    HAVING (COUNT (DISTINCT ?filmr) > 50)
}

} GROUP BY ?genrer
LIMIT 500

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('genrer', 'http://www.wikidata.org/entity/Q471839'), ('callret-1', 'science fiction film'), ('totalFilmCount', '1466'), ('numberOfYearsPassed', '18')]
# [('genrer', 'http://www.wikidata.org/entity/Q93204'), ('callret-1', 'documentary film'), ('totalFilmCount', '19525'), ('numberOfYearsPassed', '21')]
# [('genrer', 'http://www.wikidata.org/entity/Q959790'), ('callret-1', 'crime film'), ('totalFilmCount', '2241'), ('numberOfYearsPassed', '19')]
# [('genrer', 'http://www.wikidata.org/entity/Q369747'), ('callret-1', 'war film'), ('totalFilmCount', '418'), ('numberOfYearsPassed', '7')]
# [('genrer', 'http://www.wikidata.org/entity/Q1339864'), ('callret-1', 'sport film'), ('totalFilmCount', '143'), ('numberOfYearsPassed', '1')]
# [('genrer', 'http://www.wikidata.org/entity/Q188473'), ('callret-1', 'action film'), ('totalFilmCount', '4417'), ('numberOfYearsPassed', '21')]
# [('genrer', 'http://www.wikidata.org/entity/Q1146335'), ('callret-1', 'teen film'), ('totalFilmCount', '581'), ('numberOfYearsPassed', '9')]
# [('genrer', 'http://www.wikidata.org/entity/Q157394'), ('callret-1', 'fantasy film'), ('totalFilmCount', '1310'), ('numberOfYearsPassed', '18')]
# [('genrer', 'http://www.wikidata.org/entity/Q130232'), ('callret-1', 'drama'), ('totalFilmCount', '25175'), ('numberOfYearsPassed', '21')]
# [('genrer', 'http://www.wikidata.org/entity/Q1361932'), ('callret-1', 'family film'), ('totalFilmCount', '86'), ('numberOfYearsPassed', '1')]
# [('genrer', 'http://www.wikidata.org/entity/Q17013749'), ('callret-1', 'historical film'), ('totalFilmCount', '506'), ('numberOfYearsPassed', '5')]
# [('genrer', 'http://www.wikidata.org/entity/Q2484376'), ('callret-1', 'thriller film'), ('totalFilmCount', '3965'), ('numberOfYearsPassed', '20')]
# [('genrer', 'http://www.wikidata.org/entity/Q20442589'), ('callret-1', 'LGBT-related film'), ('totalFilmCount', '2179'), ('numberOfYearsPassed', '18')]
# [('genrer', 'http://www.wikidata.org/entity/Q859369'), ('callret-1', 'comedy-drama'), ('totalFilmCount', '2406'), ('numberOfYearsPassed', '19')]
# [('genrer', 'http://www.wikidata.org/entity/Q200092'), ('callret-1', 'horror film'), ('totalFilmCount', '4485'), ('numberOfYearsPassed', '20')]
# [('genrer', 'http://www.wikidata.org/entity/Q157443'), ('callret-1', 'comedy film'), ('totalFilmCount', '10720'), ('numberOfYearsPassed', '21')]
# [('genrer', 'http://www.wikidata.org/entity/Q52207399'), ('callret-1', 'film based on a novel'), ('totalFilmCount', '275'), ('numberOfYearsPassed', '5')]
# [('genrer', 'http://www.wikidata.org/entity/Q319221'), ('callret-1', 'adventure film'), ('totalFilmCount', '999'), ('numberOfYearsPassed', '12')]
# [('genrer', 'http://www.wikidata.org/entity/Q842256'), ('callret-1', 'musical film'), ('totalFilmCount', '1271'), ('numberOfYearsPassed', '18')]
# [('genrer', 'http://www.wikidata.org/entity/Q860626'), ('callret-1', 'romantic comedy'), ('totalFilmCount', '2712'), ('numberOfYearsPassed', '18')]
# [('genrer', 'http://www.wikidata.org/entity/Q645928'), ('callret-1', 'biographical film'), ('totalFilmCount', '2258'), ('numberOfYearsPassed', '18')]
# [('genrer', 'http://www.wikidata.org/entity/Q1200678'), ('callret-1', 'mystery film'), ('totalFilmCount', '516'), ('numberOfYearsPassed', '8')]
# [('genrer', 'http://www.wikidata.org/entity/Q185529'), ('callret-1', 'pornographic film'), ('totalFilmCount', '105'), ('numberOfYearsPassed', '2')]
# [('genrer', 'http://www.wikidata.org/entity/Q1054574'), ('callret-1', 'romance film'), ('totalFilmCount', '3320'), ('numberOfYearsPassed', '19')]
# [('genrer', 'http://www.wikidata.org/entity/Q52162262'), ('callret-1', 'film based on literature'), ('totalFilmCount', '51'), ('numberOfYearsPassed', '1')]
# [('genrer', 'http://www.wikidata.org/entity/Q459290'), ('callret-1', 'independent film'), ('totalFilmCount', '106'), ('numberOfYearsPassed', '2')]
# [('genrer', 'http://www.wikidata.org/entity/Q2143665'), ('callret-1', "children's film"), ('totalFilmCount', '497'), ('numberOfYearsPassed', '9')]
# 27

# %% [markdown]
# Before inserting the filter in the final query, I would like to check if I'm calculating the right amount of years:

# %%
queryString = """
SELECT DISTINCT ?maxNumberOfYears WHERE {
    
    BIND(YEAR(NOW()) - YEAR("2001-01-01T00:00:00Z"^^xsd:dateTime)  as ?maxNumberOfYears)
}
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('maxNumberOfYears', '21')]
# 1

# %% [markdown]
# Final query for this task

# %% [markdown]
# Here the strategy is to fold the data in two steps.
# - At first (inner query), I count how many films per genre per year. In this step, I also filter the years with less than 50 fils
#
# - Then (outer query) I sum the film of each year for every genre. I also count how many "years" are left from the step above: if they are not the maximun, it means that some years had less than 50 fils, and so the genre should be excluded from the results

# %%
queryString = """
SELECT DISTINCT ?genrer SAMPLE(?genreLabel) (SUM(?filmCount) as ?totalFilmCount)
WHERE {
{
    SELECT DISTINCT ?genrer ?year (SAMPLE(?genre) as ?genreLabel) (COUNT(DISTINCT ?filmr) as ?filmCount)
    WHERE {

       # ?filmr wdt:P31 wd:Q11424;  # generic film
           # ?releaseDate ?date; # with a publication date
           wdt:P136 ?genrer.   # and a genre


       VALUES(?releasedDate){
           (wdt:P577)   # publication date
           (wdt:P1191)  # date of first performance
           (wdt:P1619)  # date of official opening
       }

          BIND(NOW() as ?now)

        FILTER (?date > "2001-01-01T00:00:00Z"^^xsd:dateTime)
        FILTER (?date < ?now) .


        BIND(YEAR(?date) as ?year)

       # get the label
       # ?genrer sc:name ?genre.
    } GROUP BY ?genrer ?year 
    HAVING (COUNT (DISTINCT ?filmr) > 50)
}

} GROUP BY ?genrer
HAVING (COUNT(?year) = (YEAR(NOW()) - YEAR("2001-01-01T00:00:00Z"^^xsd:dateTime)))
LIMIT 500

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('genrer', 'http://www.wikidata.org/entity/Q93204'), ('callret-1', 'documentary film'), ('totalFilmCount', '19525')]
# [('genrer', 'http://www.wikidata.org/entity/Q188473'), ('callret-1', 'action film'), ('totalFilmCount', '4417')]
# [('genrer', 'http://www.wikidata.org/entity/Q130232'), ('callret-1', 'drama'), ('totalFilmCount', '25175')]
# [('genrer', 'http://www.wikidata.org/entity/Q157443'), ('callret-1', 'comedy film'), ('totalFilmCount', '10720')]
# 4

# %% [markdown]
# ## Task 6
# Consider the composers of Western films and their country of citizenship. Count the number of Western Films on which worked a composer grouped by country of citizenship and return the top-10 (the result set must be country IRI, label and #films)..

# %% [markdown]
# This query and the following ones were very close to others I did in the past workflows/in the pre exam. I just copy and pasted them, while adapting the model to the one I discovered with the previous queries. After some syntax struggling, I got the results immediately.

# %% [markdown]
# Final query for this task

# %%
queryString = """
SELECT DISTINCT ?countryr  SAMPLE(?country) (COUNT (?filmr) as ?filmCount)
WHERE{
    # ?filmr wdt:P86 ?composerr.
    # ?composerr wdt:P27 ?countryr.
    
    
    
    # ?filmr wdt:P136 wd:Q172980.
    # you may use regexes to get every subgenre, such as Acid westerns.
    # if you wish to select other than pure westerns, use instead:
    # ?filmr wdt:P136 [sc:name ?genre] FILTER regex(?genre "estern").
    
    # ?countryr sc:name ?country.
    
}GROUP BY ?countryr
ORDER BY DESC (?filmCount)
LIMIT 10
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('countryr', 'http://www.wikidata.org/entity/Q30'), ('callret-1', 'United States of America'), ('filmCount', '1080')]
# [('countryr', 'http://www.wikidata.org/entity/Q145'), ('callret-1', 'United Kingdom'), ('filmCount', '59')]
# [('countryr', 'http://www.wikidata.org/entity/Q34266'), ('callret-1', 'Russian Empire'), ('filmCount', '45')]
# [('countryr', 'http://www.wikidata.org/entity/Q183'), ('callret-1', 'Germany'), ('filmCount', '45')]
# [('countryr', 'http://www.wikidata.org/entity/Q38'), ('callret-1', 'Italy'), ('filmCount', '41')]
# [('countryr', 'http://www.wikidata.org/entity/Q15180'), ('callret-1', 'Soviet Union'), ('filmCount', '36')]
# [('countryr', 'http://www.wikidata.org/entity/Q40'), ('callret-1', 'Austria'), ('filmCount', '36')]
# [('countryr', 'http://www.wikidata.org/entity/Q172579'), ('callret-1', 'Kingdom of Italy'), ('filmCount', '32')]
# [('countryr', 'http://www.wikidata.org/entity/Q28513'), ('callret-1', 'Austria-Hungary'), ('filmCount', '31')]
# [('countryr', 'http://www.wikidata.org/entity/Q142'), ('callret-1', 'France'), ('filmCount', '22')]
# 10

# %% [markdown]
# ## Task 7
# Consider the decades from 1961 to 1970, and from 2001 to 2010 and compare the total number of western films released in each one (the result set must be two couples decade and #western films of that decade).

# %% [markdown]
# Final query for this task

# %%
queryString = """
SELECT DISTINCT ?decade ?westernCount
WHERE{
    {
        SELECT (SAMPLE(?decade1) as ?decade) (COUNT (?filmr1) as ?westernCount){
           BIND("1961-1970" as ?decade1)
        
           # ?filmr1 wdt:P31 wd:Q11424;  # generic film
               # ?releaseDate1 ?date1;   # with a publication date
               wdt:P136 wd:Q172980.   # and genre = western


           VALUES(?releasedDate1){
               (wdt:P577)   # publication date
               (wdt:P1191)  # date of first performance
               (wdt:P1619)  # date of official opening
           }

            FILTER (?date1 > "1961-01-01T00:00:00Z"^^xsd:dateTime)
            FILTER (?date1 < "1970-01-01T00:00:00Z"^^xsd:dateTime) .

    } }UNION   {
        SELECT (SAMPLE(?decade2) as ?decade) (COUNT (?filmr2) as ?westernCount){
           BIND("2001-2010" as ?decade2)
        
           # ?filmr2 wdt:P31 wd:Q11424;  # generic film
               # ?releaseDate2 ?date2;   # with a publication date
               wdt:P136 wd:Q172980.   # and genre = western


           VALUES(?releasedDate2){
               (wdt:P577)   # publication date
               (wdt:P1191)  # date of first performance
               (wdt:P1619)  # date of official opening
           }

            FILTER (?date2 > "2001-01-01T00:00:00Z"^^xsd:dateTime)
            FILTER (?date2 < "2010-01-01T00:00:00Z"^^xsd:dateTime) .

    }}
}
LIMIT 10
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('decade', '1961-1970'), ('westernCount', '621')]
# [('decade', '2001-2010'), ('westernCount', '189')]
# 2

# %% [markdown]
# ## Task 8
# Consider the decades from 1961 to 1970, and from 2001 to 2010 and select only western films. Then, for each decade, compare the average cast members size per film (the result set must be two couples decade and average cast members size of that decade).

# %% [markdown]
# Let's find the "is in the cast" property:

# %%
queryString = """
SELECT DISTINCT ?pr ?p ?or ?o
WHERE {
   wd:Q206124 ?pr ?or . # Midnight in Paris, ??, ??
   # get the label
   # ?pr sc:name ?p.
   # ?or sc:name ?o.
   FILTER regex(?p, "cast", "i").
}
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('pr', 'http://www.wikidata.org/prop/direct/P161'), ('p', 'cast member'), ('or', 'http://www.wikidata.org/entity/Q104514'), ('o', 'Adrien Brody')]
# [('pr', 'http://www.wikidata.org/prop/direct/P161'), ('p', 'cast member'), ('or', 'http://www.wikidata.org/entity/Q143945'), ('o', 'Carla Bruni')]
# [('pr', 'http://www.wikidata.org/prop/direct/P161'), ('p', 'cast member'), ('or', 'http://www.wikidata.org/entity/Q17176312'), ('o', 'Laurent Claret')]
# [('pr', 'http://www.wikidata.org/prop/direct/P161'), ('p', 'cast member'), ('or', 'http://www.wikidata.org/entity/Q1930952'), ('o', 'Michel Vuillermoz')]
# [('pr', 'http://www.wikidata.org/prop/direct/P161'), ('p', 'cast member'), ('or', 'http://www.wikidata.org/entity/Q1986254'), ('o', 'Sonia Rolland')]
# [('pr', 'http://www.wikidata.org/prop/direct/P161'), ('p', 'cast member'), ('or', 'http://www.wikidata.org/entity/Q231096'), ('o', 'Léa Seydoux')]
# [('pr', 'http://www.wikidata.org/prop/direct/P161'), ('p', 'cast member'), ('or', 'http://www.wikidata.org/entity/Q237781'), ('o', 'Alison Pill')]
# [('pr', 'http://www.wikidata.org/prop/direct/P161'), ('p', 'cast member'), ('or', 'http://www.wikidata.org/entity/Q26231'), ('o', 'Corey Stoll')]
# [('pr', 'http://www.wikidata.org/prop/direct/P161'), ('p', 'cast member'), ('or', 'http://www.wikidata.org/entity/Q2682027'), ('o', 'Marcial Di Fonzo Bo')]
# [('pr', 'http://www.wikidata.org/prop/direct/P161'), ('p', 'cast member'), ('or', 'http://www.wikidata.org/entity/Q2825303'), ('o', 'Adrien de Van')]
# [('pr', 'http://www.wikidata.org/prop/direct/P161'), ('p', 'cast member'), ('or', 'http://www.wikidata.org/entity/Q2869522'), ('o', 'Atmen Kelif')]
# [('pr', 'http://www.wikidata.org/prop/direct/P161'), ('p', 'cast member'), ('or', 'http://www.wikidata.org/entity/Q2941829'), ('o', 'Catherine Benguigui')]
# [('pr', 'http://www.wikidata.org/prop/direct/P161'), ('p', 'cast member'), ('or', 'http://www.wikidata.org/entity/Q3014367'), ('o', 'Daniel Lundh')]
# [('pr', 'http://www.wikidata.org/prop/direct/P161'), ('p', 'cast member'), ('or', 'http://www.wikidata.org/entity/Q3085738'), ('o', 'François Rostain')]
# [('pr', 'http://www.wikidata.org/prop/direct/P161'), ('p', 'cast member'), ('or', 'http://www.wikidata.org/entity/Q318991'), ('o', 'Gad Elmaleh')]
# [('pr', 'http://www.wikidata.org/prop/direct/P161'), ('p', 'cast member'), ('or', 'http://www.wikidata.org/entity/Q3292235'), ('o', 'Marie-Sohna Condé')]
# [('pr', 'http://www.wikidata.org/prop/direct/P161'), ('p', 'cast member'), ('or', 'http://www.wikidata.org/entity/Q3351313'), ('o', 'Olivier Rabourdin')]
# [('pr', 'http://www.wikidata.org/prop/direct/P161'), ('p', 'cast member'), ('or', 'http://www.wikidata.org/entity/Q3524303'), ('o', 'Thierry Hancisse')]
# [('pr', 'http://www.wikidata.org/prop/direct/P161'), ('p', 'cast member'), ('or', 'http://www.wikidata.org/entity/Q4069179'), ('o', 'Nina Arianda')]
# [('pr', 'http://www.wikidata.org/prop/direct/P161'), ('p', 'cast member'), ('or', 'http://www.wikidata.org/entity/Q434661'), ('o', 'Mimi Kennedy')]
# 20

# %% [markdown]
# Final query for this task

# %%
queryString = """
SELECT DISTINCT ?decade ?castMemberAvg
WHERE{
    {
        SELECT (SAMPLE(?decade1) as ?decade) (AVG (?castMemberCount1) as ?castMemberAvg){
           BIND("1961-1970" as ?decade1)
           
           {
               SELECT DISTINCT ?filmr1 (COUNT(distinct ?castMember1) as ?castMemberCount1) WHERE {
                   # ?filmr1 wdt:P31 wd:Q11424;  # generic film
                   # ?releaseDate1 ?date1;       # with a publication date
                   wdt:P136 wd:Q172980;        # and genre = western
                   wdt:P161 ?castMember1.       # average cast member


                   VALUES(?releasedDate1){
                       (wdt:P577)   # publication date
                       (wdt:P1191)  # date of first performance
                       (wdt:P1619)  # date of official opening
                   }

                    FILTER (?date1 > "1961-01-01T00:00:00Z"^^xsd:dateTime)
                    FILTER (?date1 < "1970-01-01T00:00:00Z"^^xsd:dateTime) .
               }GROUP BY ?filmr1
           
           }
       }

    }UNION   {
        SELECT (SAMPLE(?decade2) as ?decade) (AVG (?castMemberCount2) as ?castMemberAvg){
           BIND("2001-2010" as ?decade2)
           
           {
               SELECT DISTINCT ?filmr2 (COUNT(distinct ?castMember2) as ?castMemberCount2) WHERE {
                   # ?filmr2 wdt:P31 wd:Q11424;  # generic film
                   # ?releaseDate2 ?date2;       # with a publication date
                   wdt:P136 wd:Q172980;        # and genre = western
                   wdt:P161 ?castMember2.       # average cast member


                   VALUES(?releasedDate2){
                       (wdt:P577)   # publication date
                       (wdt:P1191)  # date of first performance
                       (wdt:P1619)  # date of official opening
                   }

                   FILTER (?date2 > "2001-01-01T00:00:00Z"^^xsd:dateTime)
                   FILTER (?date2 < "2010-01-01T00:00:00Z"^^xsd:dateTime) .
               }GROUP BY ?filmr2
           
           }
       }
    }
}
LIMIT 10
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('decade', '1961-1970'), ('castMemberAvg', '12.628272251308901')]
# [('decade', '2001-2010'), ('castMemberAvg', '8.928571428571429')]
# 2

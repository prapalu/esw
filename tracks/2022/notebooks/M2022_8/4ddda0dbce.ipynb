# %% [markdown]
# # General instructions
#
# The goal of the project is to materialize a set of **exploratory workloads** over a real-world, large-scale,  open-domain KG: [WikiData](https://www.wikidata.org/wiki/Wikidata:Main_Page)
#
# An exploratory workload  is composed by a set of queries, where each query is related to the information obtained previously.
#
# An exploratory workload starts with a usually vague, open ended question, and does not assume the person issuing the workload has a clear understanding of the data contained in the target database or its structure.
#
# Remeber that:
#
# 1. All the queries must run in the python notebook
# 2. You can use classes and properties only if you find them via a SPARQL query that must be present in the notebook
# 3. You do not delete useless queries. Keep everything that is synthatically valid
#
# ```
# ?p <http://schema.org/name> ?name .
# ```
#
#     is the BGP returning a human-readable name of a property or a class in Wikidata.

# %%
## SETUP used later

from SPARQLWrapper import SPARQLWrapper, JSON


prefixString = """
##-4ddda0dbce-##
PREFIX wd: <http://www.wikidata.org/entity/> 
PREFIX wdt: <http://www.wikidata.org/prop/direct/> 
PREFIX sc: <http://schema.org/>
"""

# select and construct queries
def run_query(queryString,verbose = True):
    to_run = prefixString + "\n" + queryString

    sparql = SPARQLWrapper("http://a256-gc1-03.srv.aau.dk:5820/sparql")
    sparql.setTimeout(300)
    sparql.setReturnFormat(JSON)
    sparql.setQuery(to_run)

    try :
        results = sparql.query()
        json_results = results.convert()
        if len(json_results['results']['bindings'])==0:
            print("Empty")
            return []
        array = []
        for bindings in json_results['results']['bindings']:
            app =  [ (var, value['value'])  for var, value in bindings.items() ] 
            if verbose:
                print( app)
            array.append(app)
        if verbose:
            print(len(array))
        return array

    except Exception as e :
        print("The operation failed", e)
    
# ASk queries
def run_ask_query(queryString):
    to_run = prefixString + "\n" + queryString

    sparql = SPARQLWrapper("http://a256-gc1-03.srv.aau.dk:5820/sparql")
    sparql.setTimeout(300)
    sparql.setReturnFormat(JSON)
    sparql.setQuery(to_run)

    try :
        return sparql.query().convert()

    except Exception as e :
        print("The operation failed", e)

# %% [markdown]
# # Movie Workflow Series ("Film Genre and directors explorative search")
#
# Consider the following exploratory information need:
#
# > investigate the results concerning the different film genre over years and the directors for the cinema.

# %% [markdown]
# ## Useful URIs for the current workflow
# The following are given:
#
# | IRI           | Description   | Role      |
# | -----------   | -----------   |-----------|
# | `wdt:P1647`   | subproperty   | predicate |
# | `wdt:P31`     | instance of   | predicate |
# | `wdt:P106`    | occupation    | predicate |
# | `wdt:P279`    | subclass      | predicate |
# | `wdt:P27`     | nationality   | predicate |
# | `wdt:P3342`     | Significant person       | predicate |
# | `wd:Q5`| Human       | node |
# | `wd:Q25089`| Woody Allen       | node |
# | `wd:Q3772`| Quentin Tarantino      | node |

# %% [markdown]
# Also consider
#
# ```
# wd:Q25089 ?p ?obj .
# ```
#
# is the BGP to retrieve all **properties of Woody Allen**
#
# Please consider that when you return a resource, you should return the IRI and the label of the resource. In particular, when the task require you to identify a BGP the result set must always be a list of couples IRI - label.
#
# The workload should:
#
#
# 1. Identify the BGP for films
#
# 2. Identify the BGP for director
#
# 3. Identify the BGP for film genre
#
# 4. Find how many western films are been released in each european country from 2010-01-01 to 2015-31-12 (the result set must be country IRI, label and #films).
#
# 5. Consider only films directed by Woody Allen or Quentin Tarantino. Then consider the date of publication of these films (take the first one if there are more than one date of publication). Return the year with more films release for the two director (the result set must be two elements and for each element there must be present the director IRI, the label of the IRI, the year and the number of films).
#
# 6. Identify the BGP for Academy Awards
#
# 7. Consider films directed by Woody Allen or Quentin Tarantino separately. Return the film which won more Academy Awards for the two directors (the result set must be two elements - one related to Allen and the other related to Tarantino -  and for each element there must be present the director IRI with its label, the film IRI with its label and the number of Academy awards won).
#
# 8. Consider the set of films directed by Allen or Tarantino. Return for each Academy Award the total number of nomination of these films (the result set must be a list of triples Academy Award IRI, label and #nomination).

# %% [markdown]
# ## Task 1
# Identify the BGP for films

# %%
# query example
queryString = """
SELECT DISTINCT ?p ?name
WHERE {
   # bind something
   wd:Q25089 ?p ?obj .
   # get the label
   # ?p sc:name ?name.
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P1003'), ('name', 'National Library of Romania ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1005'), ('name', 'Portuguese National Library ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1006'), ('name', 'Nationale Thesaurus voor Auteurs ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1015'), ('name', 'NORAF ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P103'), ('name', 'native language')]
# [('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('p', 'http://www.wikidata.org/prop/direct/P108'), ('name', 'employer')]
# [('p', 'http://www.wikidata.org/prop/direct/P109'), ('name', 'signature')]
# [('p', 'http://www.wikidata.org/prop/direct/P1150'), ('name', 'Regensburg Classification')]
# [('p', 'http://www.wikidata.org/prop/direct/P1207'), ('name', 'NUKAT ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1220'), ('name', 'Internet Broadway Database person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1233'), ('name', 'Internet Speculative Fiction Database author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1263'), ('name', 'NNDB people ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1266'), ('name', 'AlloCiné person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1273'), ('name', 'CANTIC ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1280'), ('name', 'CONOR.SI ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1283'), ('name', 'filmography')]
# [('p', 'http://www.wikidata.org/prop/direct/P1284'), ('name', 'Munzinger person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1296'), ('name', 'Gran Enciclopèdia Catalana ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1303'), ('name', 'instrument')]
# [('p', 'http://www.wikidata.org/prop/direct/P1309'), ('name', 'EGAXA ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1315'), ('name', 'NLA Trove ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1317'), ('name', 'floruit')]
# [('p', 'http://www.wikidata.org/prop/direct/P1343'), ('name', 'described by source')]
# [('p', 'http://www.wikidata.org/prop/direct/P1368'), ('name', 'LNB ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1375'), ('name', 'NSK ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P138'), ('name', 'named after')]
# [('p', 'http://www.wikidata.org/prop/direct/P1411'), ('name', 'nominated for')]
# [('p', 'http://www.wikidata.org/prop/direct/P1412'), ('name', 'languages spoken, written or signed')]
# [('p', 'http://www.wikidata.org/prop/direct/P1417'), ('name', 'Encyclopædia Britannica Online ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1455'), ('name', 'list of works')]
# [('p', 'http://www.wikidata.org/prop/direct/P1477'), ('name', 'birth name')]
# [('p', 'http://www.wikidata.org/prop/direct/P1559'), ('name', 'name in native language')]
# [('p', 'http://www.wikidata.org/prop/direct/P1580'), ('name', 'University of Barcelona authority ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1607'), ('name', 'Dialnet author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P166'), ('name', 'award received')]
# [('p', 'http://www.wikidata.org/prop/direct/P1695'), ('name', 'NLP ID (unique)')]
# [('p', 'http://www.wikidata.org/prop/direct/P172'), ('name', 'ethnic group')]
# [('p', 'http://www.wikidata.org/prop/direct/P1728'), ('name', 'AllMusic artist ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1741'), ('name', 'GTAA ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P18'), ('name', 'image')]
# [('p', 'http://www.wikidata.org/prop/direct/P1816'), ('name', 'National Portrait Gallery (London) person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1819'), ('name', 'genealogics.org person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P19'), ('name', 'place of birth')]
# [('p', 'http://www.wikidata.org/prop/direct/P1953'), ('name', 'Discogs artist ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1969'), ('name', 'MovieMeter director ID (former scheme)')]
# [('p', 'http://www.wikidata.org/prop/direct/P1977'), ('name', 'Les Archives du Spectacle Person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2019'), ('name', 'AllMovie person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2031'), ('name', 'work period (start)')]
# [('p', 'http://www.wikidata.org/prop/direct/P21'), ('name', 'sex or gender')]
# [('p', 'http://www.wikidata.org/prop/direct/P213'), ('name', 'ISNI')]
# [('p', 'http://www.wikidata.org/prop/direct/P214'), ('name', 'VIAF ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2163'), ('name', 'FAST ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2168'), ('name', 'Swedish Film Database person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2174'), ('name', 'Museum of Modern Art artist ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2188'), ('name', 'BiblioNet author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2190'), ('name', 'C-SPAN person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2191'), ('name', 'Vegetti Catalog of Fantastic Literature NILF ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P22'), ('name', 'father')]
# [('p', 'http://www.wikidata.org/prop/direct/P227'), ('name', 'GND ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2387'), ('name', 'Elonet person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2435'), ('name', 'PORT person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P244'), ('name', 'Library of Congress authority ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P245'), ('name', 'Union List of Artist Names ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2469'), ('name', 'Theatricalia person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P25'), ('name', 'mother')]
# [('p', 'http://www.wikidata.org/prop/direct/P2519'), ('name', 'Scope.dk person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P26'), ('name', 'spouse')]
# [('p', 'http://www.wikidata.org/prop/direct/P2600'), ('name', 'Geni.com profile ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2604'), ('name', 'Kinopoisk person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2605'), ('name', 'ČSFD person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2626'), ('name', 'Danish National Filmography person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2638'), ('name', 'TV.com ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P264'), ('name', 'record label')]
# [('p', 'http://www.wikidata.org/prop/direct/P268'), ('name', 'Bibliothèque nationale de France ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2688'), ('name', 'Box Office Mojo person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P269'), ('name', 'IdRef ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P27'), ('name', 'country of citizenship')]
# [('p', 'http://www.wikidata.org/prop/direct/P271'), ('name', 'CiNii author ID (books)')]
# [('p', 'http://www.wikidata.org/prop/direct/P2734'), ('name', 'Unz Review author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2924'), ('name', 'Great Russian Encyclopedia Online ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2963'), ('name', 'Goodreads author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3056'), ('name', 'TCM Movie Database person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3065'), ('name', 'RERO ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('name', 'instance of')]
# [('p', 'http://www.wikidata.org/prop/direct/P3106'), ('name', 'Guardian topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3136'), ('name', 'elCinema person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3142'), ('name', 'EDb person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3219'), ('name', 'Encyclopædia Universalis ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3222'), ('name', 'NE.se ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3280'), ('name', 'BAnQ author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3305'), ('name', 'KINENOTE person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3348'), ('name', 'National Library of Greece ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3373'), ('name', 'sibling')]
# [('p', 'http://www.wikidata.org/prop/direct/P3417'), ('name', 'Quora topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3430'), ('name', 'SNAC ARK ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P345'), ('name', 'IMDb ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3478'), ('name', 'Songkick artist ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3479'), ('name', 'Omni topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P349'), ('name', 'National Diet Library ID')]
# 100

# %%
# Checking the Director Quentin Tarantino on Q3772
queryString = """
SELECT DISTINCT ?p ?name
WHERE {
   # bind something
   wd:Q3772 ?p ?object .
   # get the label
   # ?object sc:name ?name.
}
LIMIT 200
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P451'), ('name', 'Mira Sorvino')]
# [('p', 'http://www.wikidata.org/prop/direct/P166'), ('name', '48th British Academy Film Awards')]
# [('p', 'http://www.wikidata.org/prop/direct/P166'), ('name', 'Edgar Awards')]
# [('p', 'http://www.wikidata.org/prop/direct/P1411'), ('name', 'Academy Award for Best Director')]
# [('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'television actor')]
# [('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'film actor')]
# [('p', 'http://www.wikidata.org/prop/direct/P166'), ('name', 'Hungarian Order of Merit')]
# [('p', 'http://www.wikidata.org/prop/direct/P166'), ('name', 'Commandeur des Arts et des Lettres\u200e')]
# [('p', 'http://www.wikidata.org/prop/direct/P1343'), ('name', 'Lentapedia')]
# [('p', 'http://www.wikidata.org/prop/direct/P166'), ('name', "Palme d'Or")]
# [('p', 'http://www.wikidata.org/prop/direct/P166'), ('name', 'star on Hollywood Walk of Fame')]
# [('p', 'http://www.wikidata.org/prop/direct/P1412'), ('name', 'English')]
# [('p', 'http://www.wikidata.org/prop/direct/P1412'), ('name', 'German')]
# [('p', 'http://www.wikidata.org/prop/direct/P136'), ('name', 'action film')]
# [('p', 'http://www.wikidata.org/prop/direct/P6379'), ('name', 'Museum of Modern Art')]
# [('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'film director')]
# [('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'screenwriter')]
# [('p', 'http://www.wikidata.org/prop/direct/P27'), ('name', 'United States of America')]
# [('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'film producer')]
# [('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'actor')]
# [('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'director')]
# [('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'writer')]
# [('p', 'http://www.wikidata.org/prop/direct/P1411'), ('name', 'Academy Award for Best Writing, Original Screenplay')]
# [('p', 'http://www.wikidata.org/prop/direct/P166'), ('name', 'Academy Award for Best Writing, Original Screenplay')]
# [('p', 'http://www.wikidata.org/prop/direct/P463'), ('name', 'American Academy of Arts and Sciences')]
# [('p', 'http://www.wikidata.org/prop/direct/P166'), ('name', '70th Golden Globe Awards')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('name', 'human')]
# [('p', 'http://www.wikidata.org/prop/direct/P140'), ('name', 'Christianity')]
# [('p', 'http://www.wikidata.org/prop/direct/P166'), ('name', 'AAAS Fellow')]
# [('p', 'http://www.wikidata.org/prop/direct/P21'), ('name', 'male')]
# [('p', 'http://www.wikidata.org/prop/direct/P1343'), ('name', 'Obalky knih.cz')]
# [('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'film editor')]
# [('p', 'http://www.wikidata.org/prop/direct/P7763'), ('name', 'works protected by copyrights')]
# [('p', 'http://www.wikidata.org/prop/direct/P1411'), ('name', 'European Film Award for Best Non-European Film')]
# [('p', 'http://www.wikidata.org/prop/direct/P166'), ('name', 'National Board of Review Award for Best Film')]
# [('p', 'http://www.wikidata.org/prop/direct/P39'), ('name', 'President of the Jury at the Cannes Festival')]
# [('p', 'http://www.wikidata.org/prop/direct/P172'), ('name', 'Italian American')]
# [('p', 'http://www.wikidata.org/prop/direct/P172'), ('name', 'Irish Americans')]
# [('p', 'http://www.wikidata.org/prop/direct/P19'), ('name', 'Knoxville')]
# [('p', 'http://www.wikidata.org/prop/direct/P737'), ('name', 'Howard Hawks')]
# [('p', 'http://www.wikidata.org/prop/direct/P166'), ('name', 'BAFTA Award for Best Original Screenplay')]
# [('p', 'http://www.wikidata.org/prop/direct/P1411'), ('name', 'Golden Globe Award for Best Screenplay')]
# [('p', 'http://www.wikidata.org/prop/direct/P166'), ('name', 'Golden Globe Award for Best Screenplay')]
# [('p', 'http://www.wikidata.org/prop/direct/P166'), ('name', '52nd Golden Globe Awards')]
# [('p', 'http://www.wikidata.org/prop/direct/P136'), ('name', 'independent film')]
# [('p', 'http://www.wikidata.org/prop/direct/P735'), ('name', 'Quentin')]
# [('p', 'http://www.wikidata.org/prop/direct/P734'), ('name', 'Tarantino')]
# [('p', 'http://www.wikidata.org/prop/direct/P166'), ('name', 'Lumière Award, Lyon Festival of cinema')]
# [('p', 'http://www.wikidata.org/prop/direct/P166'), ('name', '36th César Awards')]
# [('p', 'http://www.wikidata.org/prop/direct/P26'), ('name', 'Daniella Pick')]
# [('p', 'http://www.wikidata.org/prop/direct/P166'), ('name', '66th British Academy Film Awards')]
# [('p', 'http://www.wikidata.org/prop/direct/P451'), ('name', 'Didem Erol')]
# [('p', 'http://www.wikidata.org/prop/direct/P22'), ('name', 'Tony Tarantino')]
# [('p', 'http://www.wikidata.org/prop/direct/P1424'), ('name', 'Template:Quentin Tarantino')]
# [('p', 'http://www.wikidata.org/prop/direct/P7084'), ('name', 'Category:Films directed by Quentin Tarantino')]
# [('p', 'http://www.wikidata.org/prop/direct/P910'), ('name', 'Category:Quentin Tarantino')]
# [('p', 'http://www.wikidata.org/prop/direct/P1283'), ('name', 'Quentin Tarantino filmography')]
# [('p', 'http://www.wikidata.org/prop/direct/P1830'), ('name', 'New Beverly Cinema')]
# 58

# %%
queryString = """
SELECT DISTINCT ?object ?name
WHERE {
   # bind something
   wd:Q3772 ?p ?object .
   # get the label
   # ?object sc:name ?name.
}
LIMIT 50
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('object', 'http://www.wikidata.org/entity/Q212026'), ('name', 'Mira Sorvino')]
# [('object', 'http://www.wikidata.org/entity/Q2566554'), ('name', '48th British Academy Film Awards')]
# [('object', 'http://www.wikidata.org/entity/Q833154'), ('name', 'Edgar Awards')]
# [('object', 'http://www.wikidata.org/entity/Q103360'), ('name', 'Academy Award for Best Director')]
# [('object', 'http://www.wikidata.org/entity/Q10798782'), ('name', 'television actor')]
# [('object', 'http://www.wikidata.org/entity/Q10800557'), ('name', 'film actor')]
# [('object', 'http://www.wikidata.org/entity/Q113068'), ('name', 'Hungarian Order of Merit')]
# [('object', 'http://www.wikidata.org/entity/Q13452531'), ('name', 'Commandeur des Arts et des Lettres\u200e')]
# [('object', 'http://www.wikidata.org/entity/Q17290934'), ('name', 'Lentapedia')]
# [('object', 'http://www.wikidata.org/entity/Q179808'), ('name', "Palme d'Or")]
# [('object', 'http://www.wikidata.org/entity/Q17985761'), ('name', 'star on Hollywood Walk of Fame')]
# [('object', 'http://www.wikidata.org/entity/Q1860'), ('name', 'English')]
# [('object', 'http://www.wikidata.org/entity/Q188'), ('name', 'German')]
# [('object', 'http://www.wikidata.org/entity/Q188473'), ('name', 'action film')]
# [('object', 'http://www.wikidata.org/entity/Q188740'), ('name', 'Museum of Modern Art')]
# [('object', 'http://www.wikidata.org/entity/Q2526255'), ('name', 'film director')]
# [('object', 'http://www.wikidata.org/entity/Q28389'), ('name', 'screenwriter')]
# [('object', 'http://www.wikidata.org/entity/Q30'), ('name', 'United States of America')]
# [('object', 'http://www.wikidata.org/entity/Q3282637'), ('name', 'film producer')]
# [('object', 'http://www.wikidata.org/entity/Q33999'), ('name', 'actor')]
# [('object', 'http://www.wikidata.org/entity/Q3455803'), ('name', 'director')]
# [('object', 'http://www.wikidata.org/entity/Q36180'), ('name', 'writer')]
# [('object', 'http://www.wikidata.org/entity/Q41417'), ('name', 'Academy Award for Best Writing, Original Screenplay')]
# [('object', 'http://www.wikidata.org/entity/Q463303'), ('name', 'American Academy of Arts and Sciences')]
# [('object', 'http://www.wikidata.org/entity/Q490861'), ('name', '70th Golden Globe Awards')]
# [('object', 'http://www.wikidata.org/entity/Q5'), ('name', 'human')]
# [('object', 'http://www.wikidata.org/entity/Q5043'), ('name', 'Christianity')]
# [('object', 'http://www.wikidata.org/entity/Q52382875'), ('name', 'AAAS Fellow')]
# [('object', 'http://www.wikidata.org/entity/Q6581097'), ('name', 'male')]
# [('object', 'http://www.wikidata.org/entity/Q67311526'), ('name', 'Obalky knih.cz')]
# [('object', 'http://www.wikidata.org/entity/Q7042855'), ('name', 'film editor')]
# [('object', 'http://www.wikidata.org/entity/Q73555012'), ('name', 'works protected by copyrights')]
# [('object', 'http://www.wikidata.org/entity/Q1377772'), ('name', 'European Film Award for Best Non-European Film')]
# [('object', 'http://www.wikidata.org/entity/Q1789102'), ('name', 'National Board of Review Award for Best Film')]
# [('object', 'http://www.wikidata.org/entity/Q23958341'), ('name', 'President of the Jury at the Cannes Festival')]
# [('object', 'http://www.wikidata.org/entity/Q974693'), ('name', 'Italian American')]
# [('object', 'http://www.wikidata.org/entity/Q1075293'), ('name', 'Irish Americans')]
# [('object', 'http://www.wikidata.org/entity/Q185582'), ('name', 'Knoxville')]
# [('object', 'http://www.wikidata.org/entity/Q51581'), ('name', 'Howard Hawks')]
# [('object', 'http://www.wikidata.org/entity/Q41375'), ('name', 'BAFTA Award for Best Original Screenplay')]
# [('object', 'http://www.wikidata.org/entity/Q849124'), ('name', 'Golden Globe Award for Best Screenplay')]
# [('object', 'http://www.wikidata.org/entity/Q93439'), ('name', '52nd Golden Globe Awards')]
# [('object', 'http://www.wikidata.org/entity/Q459290'), ('name', 'independent film')]
# [('object', 'http://www.wikidata.org/entity/Q1158484'), ('name', 'Quentin')]
# [('object', 'http://www.wikidata.org/entity/Q21487819'), ('name', 'Tarantino')]
# [('object', 'http://www.wikidata.org/entity/Q3404975'), ('name', 'Lumière Award, Lyon Festival of cinema')]
# [('object', 'http://www.wikidata.org/entity/Q245949'), ('name', '36th César Awards')]
# [('object', 'http://www.wikidata.org/entity/Q32947601'), ('name', 'Daniella Pick')]
# [('object', 'http://www.wikidata.org/entity/Q2690424'), ('name', '66th British Academy Film Awards')]
# [('object', 'http://www.wikidata.org/entity/Q5274115'), ('name', 'Didem Erol')]
# 50

# %%
queryString = """
SELECT DISTINCT ?p ?name 
WHERE {
    # bind something
    wd:Q188473 ?p ?object .
    # get the label
    # ?p sc:name ?name.
}
LIMIT 30
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P1813'), ('name', 'short name')]
# [('p', 'http://www.wikidata.org/prop/direct/P227'), ('name', 'GND ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2347'), ('name', 'YSO ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2354'), ('name', 'has list')]
# [('p', 'http://www.wikidata.org/prop/direct/P2581'), ('name', 'BabelNet ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('name', 'subclass of')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('name', 'instance of')]
# [('p', 'http://www.wikidata.org/prop/direct/P3569'), ('name', 'Cultureel Woordenboek ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P373'), ('name', 'Commons category')]
# [('p', 'http://www.wikidata.org/prop/direct/P508'), ('name', 'BNCF Thesaurus ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P646'), ('name', 'Freebase ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8408'), ('name', 'KBpedia ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P910'), ('name', "topic's main category")]
# [('p', 'http://www.wikidata.org/prop/direct/P9084'), ('name', 'ABC News topic ID')]
# 14

# %%
# Using subClass P279 with action film Q188473

queryString = """
SELECT DISTINCT ?object ?name 
WHERE {
    # bind something
    wd:Q188473 wdt:P279 ?object .
    # get the label
    # ?object sc:name ?name.
    FILTER(REGEX(?name,"film"))
    
}
LIMIT 30
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('object', 'http://www.wikidata.org/entity/Q11424'), ('name', 'film')]
# 1

# %% [markdown]
# Final query for this task

# %%
# write your final query
# Retrived BGP for film

queryString = """
SELECT DISTINCT ?object ?name
WHERE {
   # bind something
   wd:Q11424 ?object ?o.
   # get the label
   # ?object sc:name ?name.
  
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('object', 'http://www.wikidata.org/prop/direct/P1014'), ('name', 'Art & Architecture Thesaurus ID')]
# [('object', 'http://www.wikidata.org/prop/direct/P1036'), ('name', 'Dewey Decimal Classification')]
# [('object', 'http://www.wikidata.org/prop/direct/P1051'), ('name', 'PSH ID')]
# [('object', 'http://www.wikidata.org/prop/direct/P1151'), ('name', "topic's main Wikimedia portal")]
# [('object', 'http://www.wikidata.org/prop/direct/P1225'), ('name', 'U.S. National Archives Identifier')]
# [('object', 'http://www.wikidata.org/prop/direct/P1245'), ('name', 'OmegaWiki Defined Meaning')]
# [('object', 'http://www.wikidata.org/prop/direct/P1256'), ('name', 'Iconclass notation')]
# [('object', 'http://www.wikidata.org/prop/direct/P1343'), ('name', 'described by source')]
# [('object', 'http://www.wikidata.org/prop/direct/P1368'), ('name', 'LNB ID')]
# [('object', 'http://www.wikidata.org/prop/direct/P1417'), ('name', 'Encyclopædia Britannica Online ID')]
# [('object', 'http://www.wikidata.org/prop/direct/P1424'), ('name', "topic's main template")]
# [('object', 'http://www.wikidata.org/prop/direct/P1617'), ('name', 'BBC Things ID')]
# [('object', 'http://www.wikidata.org/prop/direct/P1709'), ('name', 'equivalent class')]
# [('object', 'http://www.wikidata.org/prop/direct/P18'), ('name', 'image')]
# [('object', 'http://www.wikidata.org/prop/direct/P1889'), ('name', 'different from')]
# [('object', 'http://www.wikidata.org/prop/direct/P1963'), ('name', 'properties for this type')]
# [('object', 'http://www.wikidata.org/prop/direct/P2167'), ('name', 'UNSPSC Code')]
# [('object', 'http://www.wikidata.org/prop/direct/P227'), ('name', 'GND ID')]
# [('object', 'http://www.wikidata.org/prop/direct/P2347'), ('name', 'YSO ID')]
# [('object', 'http://www.wikidata.org/prop/direct/P244'), ('name', 'Library of Congress authority ID')]
# [('object', 'http://www.wikidata.org/prop/direct/P2579'), ('name', 'studied by')]
# [('object', 'http://www.wikidata.org/prop/direct/P2581'), ('name', 'BabelNet ID')]
# [('object', 'http://www.wikidata.org/prop/direct/P2612'), ('name', 'TED topic ID')]
# [('object', 'http://www.wikidata.org/prop/direct/P268'), ('name', 'Bibliothèque nationale de France ID')]
# [('object', 'http://www.wikidata.org/prop/direct/P279'), ('name', 'subclass of')]
# [('object', 'http://www.wikidata.org/prop/direct/P2888'), ('name', 'exact match')]
# [('object', 'http://www.wikidata.org/prop/direct/P2959'), ('name', 'permanent duplicated item')]
# [('object', 'http://www.wikidata.org/prop/direct/P3106'), ('name', 'Guardian topic ID')]
# [('object', 'http://www.wikidata.org/prop/direct/P3221'), ('name', 'New York Times topic ID')]
# [('object', 'http://www.wikidata.org/prop/direct/P3417'), ('name', 'Quora topic ID')]
# [('object', 'http://www.wikidata.org/prop/direct/P349'), ('name', 'National Diet Library ID')]
# [('object', 'http://www.wikidata.org/prop/direct/P3553'), ('name', 'Zhihu topic ID')]
# [('object', 'http://www.wikidata.org/prop/direct/P373'), ('name', 'Commons category')]
# [('object', 'http://www.wikidata.org/prop/direct/P3827'), ('name', 'JSTOR topic ID')]
# [('object', 'http://www.wikidata.org/prop/direct/P3832'), ('name', 'Europeana Fashion Vocabulary ID')]
# [('object', 'http://www.wikidata.org/prop/direct/P3911'), ('name', 'STW Thesaurus for Economics ID')]
# [('object', 'http://www.wikidata.org/prop/direct/P3916'), ('name', 'UNESCO Thesaurus ID')]
# [('object', 'http://www.wikidata.org/prop/direct/P3921'), ('name', 'Wikidata SPARQL query equivalent')]
# [('object', 'http://www.wikidata.org/prop/direct/P3984'), ('name', 'subreddit')]
# [('object', 'http://www.wikidata.org/prop/direct/P4527'), ('name', 'UK Parliament thesaurus ID')]
# [('object', 'http://www.wikidata.org/prop/direct/P460'), ('name', 'said to be the same as')]
# [('object', 'http://www.wikidata.org/prop/direct/P486'), ('name', 'MeSH descriptor ID')]
# [('object', 'http://www.wikidata.org/prop/direct/P4953'), ('name', 'Library of Congress Genre/Form Terms ID')]
# [('object', 'http://www.wikidata.org/prop/direct/P5008'), ('name', 'on focus list of Wikimedia project')]
# [('object', 'http://www.wikidata.org/prop/direct/P508'), ('name', 'BNCF Thesaurus ID')]
# [('object', 'http://www.wikidata.org/prop/direct/P5125'), ('name', 'Wikimedia outline')]
# [('object', 'http://www.wikidata.org/prop/direct/P5198'), ('name', 'ASC Leiden Thesaurus ID')]
# [('object', 'http://www.wikidata.org/prop/direct/P5250'), ('name', 'IAB code')]
# [('object', 'http://www.wikidata.org/prop/direct/P527'), ('name', 'has part')]
# [('object', 'http://www.wikidata.org/prop/direct/P5357'), ('name', 'The Encyclopedia of Science Fiction ID')]
# [('object', 'http://www.wikidata.org/prop/direct/P5869'), ('name', 'model item')]
# [('object', 'http://www.wikidata.org/prop/direct/P6104'), ('name', 'maintained by WikiProject')]
# [('object', 'http://www.wikidata.org/prop/direct/P6186'), ('name', 'category for eponymous categories')]
# [('object', 'http://www.wikidata.org/prop/direct/P6200'), ('name', 'BBC News topic ID')]
# [('object', 'http://www.wikidata.org/prop/direct/P6328'), ('name', 'Politika topic ID')]
# [('object', 'http://www.wikidata.org/prop/direct/P646'), ('name', 'Freebase ID')]
# [('object', 'http://www.wikidata.org/prop/direct/P6573'), ('name', 'Klexikon article ID')]
# [('object', 'http://www.wikidata.org/prop/direct/P7033'), ('name', 'Australian Educational Vocabulary ID')]
# [('object', 'http://www.wikidata.org/prop/direct/P7497'), ('name', 'Wolfram Language entity type')]
# [('object', 'http://www.wikidata.org/prop/direct/P7685'), ('name', 'CALS Encyclopedia of Arkansas ID')]
# [('object', 'http://www.wikidata.org/prop/direct/P7688'), ('name', 'Mississippi Encyclopedia ID')]
# [('object', 'http://www.wikidata.org/prop/direct/P7749'), ('name', 'Nomenclature for Museum Cataloging')]
# [('object', 'http://www.wikidata.org/prop/direct/P7818'), ('name', 'French Vikidia ID')]
# [('object', 'http://www.wikidata.org/prop/direct/P7827'), ('name', 'Spanish Vikidia ID')]
# [('object', 'http://www.wikidata.org/prop/direct/P7952'), ('name', 'The First Amendment Encyclopedia ID')]
# [('object', 'http://www.wikidata.org/prop/direct/P8309'), ('name', 'Yle topic ID')]
# [('object', 'http://www.wikidata.org/prop/direct/P8408'), ('name', 'KBpedia ID')]
# [('object', 'http://www.wikidata.org/prop/direct/P8519'), ('name', 'RKD thesaurus ID')]
# [('object', 'http://www.wikidata.org/prop/direct/P8672'), ('name', 'Twitter topic ID')]
# [('object', 'http://www.wikidata.org/prop/direct/P8972'), ('name', 'small logo or icon')]
# [('object', 'http://www.wikidata.org/prop/direct/P910'), ('name', "topic's main category")]
# [('object', 'http://www.wikidata.org/prop/direct/P9318'), ('name', 'Ávvir topic ID')]
# [('object', 'http://www.wikidata.org/prop/direct/P950'), ('name', 'Biblioteca Nacional de España ID')]
# [('object', 'http://www.wikidata.org/prop/direct/P9545'), ('name', 'Encyclopedia of China Online Database ID')]
# [('object', 'http://www.wikidata.org/prop/direct/P7697'), ('name', 'Maine: An Encyclopedia ID')]
# 75

# %% [markdown]
# ## Task 2
# Identify the BGP for director

# %%
# write your queries
# cHECK the details of Director node on Q3455803 FROM THE previous Result

queryString = """
SELECT DISTINCT ?object ?name
WHERE {
   # bind something
   wd:Q3455803 ?p ?object .
   # get the label
   # ?object sc:name ?name.
}
LIMIT 50
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('object', 'http://www.wikidata.org/entity/Q5870903'), ('name', 'Category:Directors')]
# [('object', 'http://www.wikidata.org/entity/Q28640'), ('name', 'profession')]
# [('object', 'http://www.wikidata.org/entity/Q483501'), ('name', 'artist')]
# [('object', 'http://www.wikidata.org/entity/Q2137554'), ('name', 'direction')]
# [('object', 'http://www.wikidata.org/entity/Q2462658'), ('name', 'manager')]
# [('object', 'http://www.wikidata.org/entity/Q2500638'), ('name', 'creator')]
# [('object', 'http://www.wikidata.org/entity/Q2607241'), ('name', 'mise en scène')]
# [('object', 'http://www.wikidata.org/entity/Q8104450'), ('name', 'Category:Wikipedia categories named after filmmakers')]
# [('object', 'http://www.wikidata.org/entity/P57'), ('name', 'director')]
# [('object', 'http://www.wikidata.org/entity/Q10809861'), ('name', 'Template:Infobox film director')]
# 10

# %%
# write your queries
# cHECK the details of Director node on Q3455803 FROM THE previous Result
# [('object', 'http://www.wikidata.org/entity/P57'), ('name', 'director')]


queryString = """
SELECT DISTINCT ?object ?name
WHERE {
   # bind something
   wd:Q971865 wdt:P57 ?object .
   # get the label
   # ?object sc:name ?name.
}
LIMIT 50
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('object', 'http://www.wikidata.org/entity/Q25089'), ('name', 'Woody Allen')]
# [('object', 'http://www.wikidata.org/entity/Q27351'), ('name', 'Senkichi Taniguchi')]
# 2

# %%
# write your queries
# cHECK the details of Director node on Q3455803 FROM THE previous Result
# [('object', 'http://www.wikidata.org/entity/P57'), ('name', 'director')]
# We just need director to search for BGP so 

queryString = """
SELECT DISTINCT ?object ?name
WHERE {
   # bind something
   wd:Q971865 ?object wd:Q27351;
   # ?p wd:Q25089.
   # get the label
   # ?object sc:name ?name.
}
LIMIT 50
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('object', 'http://www.wikidata.org/prop/direct/P57'), ('name', 'director')]
# 1

# %%
# write your queries
# cHECK the details of Director node on Q3455803 FROM THE previous Result
# [('object', 'http://www.wikidata.org/entity/P57'), ('name', 'director')]
# We just need director to search for BGP

# we Have Retrivied BGP for Director



queryString = """
SELECT DISTINCT ?object ?name
WHERE {
   # bind something
   wd:Q971865 ?object ?o.
   # get the label
   # ?object sc:name ?name.
    
}
LIMIT 500
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('object', 'http://www.wikidata.org/prop/direct/P1237'), ('name', 'Box Office Mojo film ID (former scheme)')]
# [('object', 'http://www.wikidata.org/prop/direct/P1258'), ('name', 'Rotten Tomatoes ID')]
# [('object', 'http://www.wikidata.org/prop/direct/P1265'), ('name', 'AlloCiné film ID')]
# [('object', 'http://www.wikidata.org/prop/direct/P136'), ('name', 'genre')]
# [('object', 'http://www.wikidata.org/prop/direct/P1417'), ('name', 'Encyclopædia Britannica Online ID')]
# [('object', 'http://www.wikidata.org/prop/direct/P1476'), ('name', 'title')]
# [('object', 'http://www.wikidata.org/prop/direct/P1562'), ('name', 'AllMovie title ID')]
# [('object', 'http://www.wikidata.org/prop/direct/P161'), ('name', 'cast member')]
# [('object', 'http://www.wikidata.org/prop/direct/P162'), ('name', 'producer')]
# [('object', 'http://www.wikidata.org/prop/direct/P1712'), ('name', 'Metacritic ID')]
# [('object', 'http://www.wikidata.org/prop/direct/P175'), ('name', 'performer')]
# [('object', 'http://www.wikidata.org/prop/direct/P1874'), ('name', 'Netflix ID')]
# [('object', 'http://www.wikidata.org/prop/direct/P1970'), ('name', 'MovieMeter film ID')]
# [('object', 'http://www.wikidata.org/prop/direct/P1981'), ('name', 'FSK film rating')]
# [('object', 'http://www.wikidata.org/prop/direct/P2047'), ('name', 'duration')]
# [('object', 'http://www.wikidata.org/prop/direct/P214'), ('name', 'VIAF ID')]
# [('object', 'http://www.wikidata.org/prop/direct/P2334'), ('name', 'Swedish Film Database film ID')]
# [('object', 'http://www.wikidata.org/prop/direct/P2346'), ('name', 'Elonet movie ID')]
# [('object', 'http://www.wikidata.org/prop/direct/P244'), ('name', 'Library of Congress authority ID')]
# [('object', 'http://www.wikidata.org/prop/direct/P2529'), ('name', 'ČSFD film ID')]
# [('object', 'http://www.wikidata.org/prop/direct/P2603'), ('name', 'Kinopoisk film ID')]
# [('object', 'http://www.wikidata.org/prop/direct/P2631'), ('name', 'TCM Movie Database film ID')]
# [('object', 'http://www.wikidata.org/prop/direct/P2638'), ('name', 'TV.com ID')]
# [('object', 'http://www.wikidata.org/prop/direct/P2704'), ('name', 'EIDR content ID')]
# [('object', 'http://www.wikidata.org/prop/direct/P272'), ('name', 'production company')]
# [('object', 'http://www.wikidata.org/prop/direct/P31'), ('name', 'instance of')]
# [('object', 'http://www.wikidata.org/prop/direct/P3107'), ('name', 'LdiF ID')]
# [('object', 'http://www.wikidata.org/prop/direct/P3129'), ('name', 'cine.gr film ID')]
# [('object', 'http://www.wikidata.org/prop/direct/P3138'), ('name', 'OFDb film ID')]
# [('object', 'http://www.wikidata.org/prop/direct/P3143'), ('name', 'elFilm film ID')]
# [('object', 'http://www.wikidata.org/prop/direct/P3203'), ('name', 'Ciné-Ressources film ID')]
# [('object', 'http://www.wikidata.org/prop/direct/P3212'), ('name', 'ISAN')]
# [('object', 'http://www.wikidata.org/prop/direct/P344'), ('name', 'director of photography')]
# [('object', 'http://www.wikidata.org/prop/direct/P345'), ('name', 'IMDb ID')]
# [('object', 'http://www.wikidata.org/prop/direct/P3593'), ('name', 'AFI Catalog of Feature Films ID')]
# [('object', 'http://www.wikidata.org/prop/direct/P364'), ('name', 'original language of film or TV show')]
# [('object', 'http://www.wikidata.org/prop/direct/P3804'), ('name', 'TV Guide show ID (former scheme)')]
# [('object', 'http://www.wikidata.org/prop/direct/P3844'), ('name', 'Deutsche Synchronkartei film ID')]
# [('object', 'http://www.wikidata.org/prop/direct/P3933'), ('name', 'Cinema.de ID')]
# [('object', 'http://www.wikidata.org/prop/direct/P436'), ('name', 'MusicBrainz release group ID')]
# [('object', 'http://www.wikidata.org/prop/direct/P437'), ('name', 'distribution format')]
# [('object', 'http://www.wikidata.org/prop/direct/P4529'), ('name', 'Douban film ID')]
# [('object', 'http://www.wikidata.org/prop/direct/P462'), ('name', 'color')]
# [('object', 'http://www.wikidata.org/prop/direct/P480'), ('name', 'FilmAffinity ID')]
# [('object', 'http://www.wikidata.org/prop/direct/P4947'), ('name', 'TMDb movie ID')]
# [('object', 'http://www.wikidata.org/prop/direct/P495'), ('name', 'country of origin')]
# [('object', 'http://www.wikidata.org/prop/direct/P5032'), ('name', 'Filmweb.pl film ID')]
# [('object', 'http://www.wikidata.org/prop/direct/P5099'), ('name', 'Il mondo dei doppiatori ID')]
# [('object', 'http://www.wikidata.org/prop/direct/P57'), ('name', 'director')]
# [('object', 'http://www.wikidata.org/prop/direct/P577'), ('name', 'publication date')]
# [('object', 'http://www.wikidata.org/prop/direct/P5786'), ('name', 'Moviepilot.de film ID')]
# [('object', 'http://www.wikidata.org/prop/direct/P58'), ('name', 'screenwriter')]
# [('object', 'http://www.wikidata.org/prop/direct/P6127'), ('name', 'Letterboxd film ID')]
# [('object', 'http://www.wikidata.org/prop/direct/P646'), ('name', 'Freebase ID')]
# [('object', 'http://www.wikidata.org/prop/direct/P750'), ('name', 'distributed by')]
# [('object', 'http://www.wikidata.org/prop/direct/P840'), ('name', 'narrative location')]
# [('object', 'http://www.wikidata.org/prop/direct/P86'), ('name', 'composer')]
# [('object', 'http://www.wikidata.org/prop/direct/P905'), ('name', 'PORT film ID')]
# [('object', 'http://www.wikidata.org/prop/direct/P950'), ('name', 'Biblioteca Nacional de España ID')]
# 59

# %% [markdown]
# Final query for this task

# %% [markdown]
# ## Task 3
# Identify the BGP for film genre

# %%
# write your queries

# [('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'director')]

queryString = """
SELECT DISTINCT ?p ?name
WHERE {

   wd:Q25089 ?p ?object .
   # ?p sc:name ?pName.
   # ?p sc:name ?name
   
}
LIMIT 30
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P1003'), ('name', 'National Library of Romania ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1005'), ('name', 'Portuguese National Library ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1006'), ('name', 'Nationale Thesaurus voor Auteurs ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1015'), ('name', 'NORAF ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P103'), ('name', 'native language')]
# [('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('p', 'http://www.wikidata.org/prop/direct/P108'), ('name', 'employer')]
# [('p', 'http://www.wikidata.org/prop/direct/P109'), ('name', 'signature')]
# [('p', 'http://www.wikidata.org/prop/direct/P1150'), ('name', 'Regensburg Classification')]
# [('p', 'http://www.wikidata.org/prop/direct/P1207'), ('name', 'NUKAT ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1220'), ('name', 'Internet Broadway Database person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1233'), ('name', 'Internet Speculative Fiction Database author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1263'), ('name', 'NNDB people ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1266'), ('name', 'AlloCiné person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1273'), ('name', 'CANTIC ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1280'), ('name', 'CONOR.SI ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1283'), ('name', 'filmography')]
# [('p', 'http://www.wikidata.org/prop/direct/P1284'), ('name', 'Munzinger person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1296'), ('name', 'Gran Enciclopèdia Catalana ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1303'), ('name', 'instrument')]
# [('p', 'http://www.wikidata.org/prop/direct/P1309'), ('name', 'EGAXA ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1315'), ('name', 'NLA Trove ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1317'), ('name', 'floruit')]
# [('p', 'http://www.wikidata.org/prop/direct/P1343'), ('name', 'described by source')]
# [('p', 'http://www.wikidata.org/prop/direct/P1368'), ('name', 'LNB ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1375'), ('name', 'NSK ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P138'), ('name', 'named after')]
# [('p', 'http://www.wikidata.org/prop/direct/P1411'), ('name', 'nominated for')]
# [('p', 'http://www.wikidata.org/prop/direct/P1412'), ('name', 'languages spoken, written or signed')]
# [('p', 'http://www.wikidata.org/prop/direct/P1417'), ('name', 'Encyclopædia Britannica Online ID')]
# 30

# %%
# write your queries

# Now I will try to look All the objects of Q25089
queryString = """
SELECT DISTINCT ?object ?name
WHERE {

   wd:Q25089 ?p ?object .
   # ?p sc:name ?pName.
   # ?object sc:name ?name
   
}
LIMIT 50
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('object', 'http://www.wikidata.org/entity/Q349357'), ('name', 'Woody Herman')]
# [('object', 'http://www.wikidata.org/entity/Q1140914'), ('name', 'Soon-Yi Previn')]
# [('object', 'http://www.wikidata.org/entity/Q22673707'), ('name', 'Bechet Dumaine Allen')]
# [('object', 'http://www.wikidata.org/entity/Q22673708'), ('name', 'Manzie Tio Allen')]
# [('object', 'http://www.wikidata.org/entity/Q18426'), ('name', 'The Bronx')]
# [('object', 'http://www.wikidata.org/entity/Q102642'), ('name', 'Diane Keaton')]
# [('object', 'http://www.wikidata.org/entity/Q3404523'), ('name', 'David di Donatello for Best Foreign Actor')]
# [('object', 'http://www.wikidata.org/entity/Q599316'), ('name', 'New School')]
# [('object', 'http://www.wikidata.org/entity/Q19961034'), ('name', 'Woody')]
# [('object', 'http://www.wikidata.org/entity/Q206124'), ('name', 'Midnight in Paris')]
# [('object', 'http://www.wikidata.org/entity/Q3831197'), ('name', 'Letty Aronson')]
# [('object', 'http://www.wikidata.org/entity/Q31579'), ('name', 'David di Donatello')]
# [('object', 'http://www.wikidata.org/entity/Q3241784'), ('name', 'Golden Lion for Lifetime Achievements')]
# [('object', 'http://www.wikidata.org/entity/Q50616934'), ('name', 'honorary doctorate of Pompeu Fabra University')]
# [('object', 'http://www.wikidata.org/entity/Q3404587'), ('name', 'FIPRESCI Prize of the Festival de Cannes')]
# [('object', 'http://www.wikidata.org/entity/Q2455835'), ('name', 'Woody Allen filmography')]
# [('object', 'http://www.wikidata.org/entity/Q971865'), ('name', "What's Up, Tiger Lily?")]
# [('object', 'http://www.wikidata.org/entity/Q3822438'), ('name', 'Butaca Awards')]
# [('object', 'http://www.wikidata.org/entity/Q103360'), ('name', 'Academy Award for Best Director')]
# [('object', 'http://www.wikidata.org/entity/Q10800557'), ('name', 'film actor')]
# [('object', 'http://www.wikidata.org/entity/Q13452531'), ('name', 'Commandeur des Arts et des Lettres\u200e')]
# [('object', 'http://www.wikidata.org/entity/Q139184'), ('name', 'BAFTA Award for Best Film')]
# [('object', 'http://www.wikidata.org/entity/Q15981151'), ('name', 'jazz musician')]
# [('object', 'http://www.wikidata.org/entity/Q174389'), ('name', 'César Award')]
# [('object', 'http://www.wikidata.org/entity/Q1860'), ('name', 'English')]
# [('object', 'http://www.wikidata.org/entity/Q18844224'), ('name', 'science fiction writer')]
# [('object', 'http://www.wikidata.org/entity/Q188740'), ('name', 'Museum of Modern Art')]
# [('object', 'http://www.wikidata.org/entity/Q1930187'), ('name', 'journalist')]
# [('object', 'http://www.wikidata.org/entity/Q214917'), ('name', 'playwright')]
# [('object', 'http://www.wikidata.org/entity/Q245068'), ('name', 'comedian')]
# [('object', 'http://www.wikidata.org/entity/Q2526255'), ('name', 'film director')]
# [('object', 'http://www.wikidata.org/entity/Q2648323'), ('name', 'Allen')]
# [('object', 'http://www.wikidata.org/entity/Q28389'), ('name', 'screenwriter')]
# [('object', 'http://www.wikidata.org/entity/Q288928'), ('name', 'agnosticism')]
# [('object', 'http://www.wikidata.org/entity/Q30'), ('name', 'United States of America')]
# [('object', 'http://www.wikidata.org/entity/Q3282637'), ('name', 'film producer')]
# [('object', 'http://www.wikidata.org/entity/Q36180'), ('name', 'writer')]
# [('object', 'http://www.wikidata.org/entity/Q36834'), ('name', 'composer')]
# [('object', 'http://www.wikidata.org/entity/Q41417'), ('name', 'Academy Award for Best Writing, Original Screenplay')]
# [('object', 'http://www.wikidata.org/entity/Q463303'), ('name', 'American Academy of Arts and Sciences')]
# [('object', 'http://www.wikidata.org/entity/Q482980'), ('name', 'author')]
# [('object', 'http://www.wikidata.org/entity/Q5'), ('name', 'human')]
# [('object', 'http://www.wikidata.org/entity/Q52382875'), ('name', 'AAAS Fellow')]
# [('object', 'http://www.wikidata.org/entity/Q58488719'), ('name', 'Billy Ireland Cartoon Library & Museum biographical files')]
# [('object', 'http://www.wikidata.org/entity/Q639669'), ('name', 'musician')]
# [('object', 'http://www.wikidata.org/entity/Q6581097'), ('name', 'male')]
# [('object', 'http://www.wikidata.org/entity/Q67311526'), ('name', 'Obalky knih.cz')]
# [('object', 'http://www.wikidata.org/entity/Q708135'), ('name', 'Silver Bear')]
# [('object', 'http://www.wikidata.org/entity/Q73555012'), ('name', 'works protected by copyrights')]
# [('object', 'http://www.wikidata.org/entity/Q787148'), ('name', 'Academy Fellowship Award')]
# 50

# %%
# write your queries

# Now I will try to look All the objects of Q971865
# [('object', 'http://www.wikidata.org/entity/Q971865'), ('name', "What's Up, Tiger Lily?")]

queryString = """
SELECT DISTINCT ?object ?name
WHERE {

   wd:Q971865 ?p ?object .
   # ?object sc:name ?name
   
}
LIMIT 30
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('object', 'http://www.wikidata.org/entity/Q25089'), ('name', 'Woody Allen')]
# [('object', 'http://www.wikidata.org/entity/Q465224'), ('name', 'American International Pictures')]
# [('object', 'http://www.wikidata.org/entity/Q376138'), ('name', 'Charles H. Joffe')]
# [('object', 'http://www.wikidata.org/entity/Q6381680'), ('name', 'Kazuo Yamada')]
# [('object', 'http://www.wikidata.org/entity/Q1053608'), ('name', "The Lovin' Spoonful")]
# [('object', 'http://www.wikidata.org/entity/Q11424'), ('name', 'film')]
# [('object', 'http://www.wikidata.org/entity/Q17'), ('name', 'Japan')]
# [('object', 'http://www.wikidata.org/entity/Q1860'), ('name', 'English')]
# [('object', 'http://www.wikidata.org/entity/Q22006653'), ('name', 'color')]
# [('object', 'http://www.wikidata.org/entity/Q2297927'), ('name', 'spy film')]
# [('object', 'http://www.wikidata.org/entity/Q30'), ('name', 'United States of America')]
# [('object', 'http://www.wikidata.org/entity/Q723685'), ('name', 'video on demand')]
# [('object', 'http://www.wikidata.org/entity/Q907311'), ('name', 'Netflix')]
# [('object', 'http://www.wikidata.org/entity/Q20644797'), ('name', 'FSK 16')]
# [('object', 'http://www.wikidata.org/entity/Q875920'), ('name', 'Toho')]
# [('object', 'http://www.wikidata.org/entity/Q271861'), ('name', 'Akiko Wakabayashi')]
# [('object', 'http://www.wikidata.org/entity/Q967761'), ('name', 'John Sebastian')]
# [('object', 'http://www.wikidata.org/entity/Q12270304'), ('name', 'Mickey Rose')]
# [('object', 'http://www.wikidata.org/entity/Q273532'), ('name', 'Louise Lasser')]
# [('object', 'http://www.wikidata.org/entity/Q27351'), ('name', 'Senkichi Taniguchi')]
# [('object', 'http://www.wikidata.org/entity/Q11356032'), ('name', 'Tatsuya Mihashi')]
# [('object', 'http://www.wikidata.org/entity/Q3751773'), ('name', 'Frank Buxton')]
# [('object', 'http://www.wikidata.org/entity/Q3674850'), ('name', 'China Lee')]
# [('object', 'http://www.wikidata.org/entity/Q449493'), ('name', 'Mie Hama')]
# [('object', 'http://www.wikidata.org/entity/Q3189161'), ('name', 'Julie Bennett')]
# 25

# %%
# write your queries

# Now I will try to look All the objects of Q971865
# [('object', 'http://www.wikidata.org/entity/Q971865'), ('name', "What's Up, Tiger Lily?")]

queryString = """
SELECT DISTINCT ?p ?name
WHERE {

   wd:Q971865 ?p ?object .
   # ?p sc:name ?name
   
}
LIMIT 30
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P1237'), ('name', 'Box Office Mojo film ID (former scheme)')]
# [('p', 'http://www.wikidata.org/prop/direct/P1258'), ('name', 'Rotten Tomatoes ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1265'), ('name', 'AlloCiné film ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P136'), ('name', 'genre')]
# [('p', 'http://www.wikidata.org/prop/direct/P1417'), ('name', 'Encyclopædia Britannica Online ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1476'), ('name', 'title')]
# [('p', 'http://www.wikidata.org/prop/direct/P1562'), ('name', 'AllMovie title ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P161'), ('name', 'cast member')]
# [('p', 'http://www.wikidata.org/prop/direct/P162'), ('name', 'producer')]
# [('p', 'http://www.wikidata.org/prop/direct/P1712'), ('name', 'Metacritic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P175'), ('name', 'performer')]
# [('p', 'http://www.wikidata.org/prop/direct/P1874'), ('name', 'Netflix ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1970'), ('name', 'MovieMeter film ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1981'), ('name', 'FSK film rating')]
# [('p', 'http://www.wikidata.org/prop/direct/P2047'), ('name', 'duration')]
# [('p', 'http://www.wikidata.org/prop/direct/P214'), ('name', 'VIAF ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2334'), ('name', 'Swedish Film Database film ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2346'), ('name', 'Elonet movie ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P244'), ('name', 'Library of Congress authority ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2529'), ('name', 'ČSFD film ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2603'), ('name', 'Kinopoisk film ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2631'), ('name', 'TCM Movie Database film ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2638'), ('name', 'TV.com ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2704'), ('name', 'EIDR content ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P272'), ('name', 'production company')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('name', 'instance of')]
# [('p', 'http://www.wikidata.org/prop/direct/P3107'), ('name', 'LdiF ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3129'), ('name', 'cine.gr film ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3138'), ('name', 'OFDb film ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3143'), ('name', 'elFilm film ID')]
# 30

# %%
# write your queries

# Now I will try to look All the objects of Q971865
# [('object', 'http://www.wikidata.org/entity/Q971865'), ('name', "What's Up, Tiger Lily?")]
# [('p', 'http://www.wikidata.org/prop/direct/P136'), ('name', 'genre')]


queryString = """
SELECT DISTINCT ?object ?name
WHERE {

   wd:Q971865 wdt:P136 ?object .
   # ?object sc:name ?name
   
}
LIMIT 30
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('object', 'http://www.wikidata.org/entity/Q2297927'), ('name', 'spy film')]
# 1

# %%
# write your queries

# Now I will try to look All the objects of Q971865
# [('object', 'http://www.wikidata.org/entity/Q971865'), ('name', "What's Up, Tiger Lily?")]
# [('p', 'http://www.wikidata.org/prop/direct/P136'), ('name', 'genre')]
# [('object', 'http://www.wikidata.org/entity/Q2297927'), ('name', 'spy film')]



queryString = """
SELECT DISTINCT ?object ?name
WHERE {

   wd:Q971865 wdt:P136 ?genre .
   # ?genre wdt:P31 ?object.
   # ?object sc:name ?name
   
}
LIMIT 30
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('object', 'http://www.wikidata.org/entity/Q201658'), ('name', 'film genre')]
# 1

# %% [markdown]
# Final query for this task

# %%
# write your final query

# write your queries

# Now I will try to look All the objects of Q971865
# [('object', 'http://www.wikidata.org/entity/Q971865'), ('name', "What's Up, Tiger Lily?")]
# [('p', 'http://www.wikidata.org/prop/direct/P136'), ('name', 'genre')]
# [('object', 'http://www.wikidata.org/entity/Q2297927'), ('name', 'spy film')]

# BGP FOR  Genre movie

queryString = """
SELECT DISTINCT ?object ?name
WHERE {
   # bind something
   wd:Q201658 ?object ?o.
   # get the label
   # ?object sc:name ?name.
    
}
LIMIT 500
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('object', 'http://www.wikidata.org/prop/direct/P1014'), ('name', 'Art & Architecture Thesaurus ID')]
# [('object', 'http://www.wikidata.org/prop/direct/P1256'), ('name', 'Iconclass notation')]
# [('object', 'http://www.wikidata.org/prop/direct/P227'), ('name', 'GND ID')]
# [('object', 'http://www.wikidata.org/prop/direct/P2354'), ('name', 'has list')]
# [('object', 'http://www.wikidata.org/prop/direct/P244'), ('name', 'Library of Congress authority ID')]
# [('object', 'http://www.wikidata.org/prop/direct/P279'), ('name', 'subclass of')]
# [('object', 'http://www.wikidata.org/prop/direct/P31'), ('name', 'instance of')]
# [('object', 'http://www.wikidata.org/prop/direct/P3235'), ('name', 'PhilPapers topic')]
# [('object', 'http://www.wikidata.org/prop/direct/P3553'), ('name', 'Zhihu topic ID')]
# [('object', 'http://www.wikidata.org/prop/direct/P361'), ('name', 'part of')]
# [('object', 'http://www.wikidata.org/prop/direct/P373'), ('name', 'Commons category')]
# [('object', 'http://www.wikidata.org/prop/direct/P3827'), ('name', 'JSTOR topic ID')]
# [('object', 'http://www.wikidata.org/prop/direct/P4342'), ('name', 'Store norske leksikon ID')]
# [('object', 'http://www.wikidata.org/prop/direct/P5250'), ('name', 'IAB code')]
# [('object', 'http://www.wikidata.org/prop/direct/P5748'), ('name', 'Basisklassifikation')]
# [('object', 'http://www.wikidata.org/prop/direct/P6366'), ('name', 'Microsoft Academic ID')]
# [('object', 'http://www.wikidata.org/prop/direct/P646'), ('name', 'Freebase ID')]
# [('object', 'http://www.wikidata.org/prop/direct/P8408'), ('name', 'KBpedia ID')]
# [('object', 'http://www.wikidata.org/prop/direct/P910'), ('name', "topic's main category")]
# [('object', 'http://www.wikidata.org/prop/direct/P9760'), ('name', "Treccani's Enciclopedia del Cinema ID")]
# [('object', 'http://www.wikidata.org/prop/direct/P8225'), ('name', 'is metaclass for')]
# 21

# %% [markdown]
# ## Task 4
# Find how many western films are been released in each european country from 2010-01-01 to 2015-31-12 (the result set must be country IRI, label and #films).

# %%
# write your queries

queryString = """
SELECT DISTINCT ?films ?Sname ?country ?name
WHERE {
   # bind something
   # ?films wdt:P31 wd:Q5;
       wdt:P136 wd:Q172980;
    wdt:P27 ?country.
    
    # ?country wdt:P31 wd:Q6256;
    wdt:P30 wd:Q46.
   # get the label
   # ?films sc:name ?Sname.
   # ?country sc:name ?name
    
}
LIMIT 500
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('films', 'http://www.wikidata.org/entity/Q309240'), ('Sname', 'Jean Giraud'), ('country', 'http://www.wikidata.org/entity/Q142'), ('name', 'France')]
# 1

# %% [markdown]
# Final query for this task

# %%
# write your final query

# write your queries

queryString = """
SELECT DISTINCT ?films ?Sname ?country ?name
WHERE {
   # bind something
   # ?films wdt:P31 wd:Q5;
       wdt:P136 wd:Q172980;
    wdt:P27 ?country.
    
    # ?country wdt:P31 wd:Q6256;
    wdt:P30 wd:Q46.
   # get the label
   # ?films sc:name ?Sname.
   # ?country sc:name ?name
    
}
LIMIT 500
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('films', 'http://www.wikidata.org/entity/Q309240'), ('Sname', 'Jean Giraud'), ('country', 'http://www.wikidata.org/entity/Q142'), ('name', 'France')]
# 1

# %% [markdown]
# ## Task 5
# Consider only films directed by Woody Allen or Quentin Tarantino. Then consider the date of publication of these films (take the first one if there are more than one date of publication). Return the year with more films release for the two director (the result set must be two elements and for each element there must be present the director IRI, the label of the IRI, the year and the number of films).

# %%
# write your queries

# Director Number P57
# FILM Q11424
# WOODEY ALLEN Q25089
# SEARCH ALL THE FLIMS WHOSE IS DIRECTED BY WOODEY ALLEN
# LETS FIND PUBLICATON YEAR
queryString = """
SELECT DISTINCT ?film ?filmname ?year
WHERE {
   # bind something
   # ?film wdt:P57 wd:Q25089;
   wdt:P31 wd:Q11424;
   wdt:P577 ?year.
   # get the label
   # ?film sc:name ?filmname.
    
}
LIMIT 500
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('film', 'http://www.wikidata.org/entity/Q3986392'), ('filmname', 'The Concert for New York City'), ('year', '2001-01-01T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q206124'), ('filmname', 'Midnight in Paris'), ('year', '2011-01-01T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q206124'), ('filmname', 'Midnight in Paris'), ('year', '2011-08-18T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q682262'), ('filmname', 'Alice'), ('year', '1990-01-01T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q682262'), ('filmname', 'Alice'), ('year', '1991-02-28T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q971865'), ('filmname', "What's Up, Tiger Lily?"), ('year', '1966-01-01T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q1004531'), ('filmname', 'Bullets Over Broadway'), ('year', '1994-09-16T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q1004531'), ('filmname', 'Bullets Over Broadway'), ('year', '1995-04-20T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q1354109'), ('filmname', 'Mighty Aphrodite'), ('year', '1995-01-01T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q1354109'), ('filmname', 'Mighty Aphrodite'), ('year', '1996-08-15T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q729026'), ('filmname', 'Broadway Danny Rose'), ('year', '1984-01-01T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q729026'), ('filmname', 'Broadway Danny Rose'), ('year', '1984-08-17T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q733677'), ('filmname', 'Match Point'), ('year', '2005-05-12T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q733677'), ('filmname', 'Match Point'), ('year', '2005-12-29T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q740143'), ('filmname', 'Husbands and Wives'), ('year', '1992-01-01T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q740143'), ('filmname', 'Husbands and Wives'), ('year', '1993-02-25T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q806092'), ('filmname', 'Bananas'), ('year', '1971-01-01T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q806092'), ('filmname', 'Bananas'), ('year', '1974-08-30T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q1321004'), ('filmname', 'You Will Meet a Tall Dark Stranger'), ('year', '2010-01-01T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q1321004'), ('filmname', 'You Will Meet a Tall Dark Stranger'), ('year', '2010-12-02T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q14511869'), ('filmname', 'Magic in the Moonlight'), ('year', '2014-01-01T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q14511869'), ('filmname', 'Magic in the Moonlight'), ('year', '2014-11-13T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q14511869'), ('filmname', 'Magic in the Moonlight'), ('year', '2014-12-04T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q614009'), ('filmname', 'Anything Else'), ('year', '2003-01-01T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q187423'), ('filmname', 'Zelig'), ('year', '1983-01-01T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q187423'), ('filmname', 'Zelig'), ('year', '1983-09-30T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q27703144'), ('filmname', 'Wonder Wheel'), ('year', '2017-12-01T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q27703144'), ('filmname', 'Wonder Wheel'), ('year', '2017-12-07T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q27703144'), ('filmname', 'Wonder Wheel'), ('year', '2018-01-11T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q786585'), ('filmname', 'Sweet and Lowdown'), ('year', '1999-01-01T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q786585'), ('filmname', 'Sweet and Lowdown'), ('year', '2000-03-30T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q1052826'), ('filmname', 'Celebrity'), ('year', '1998-09-07T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q1052826'), ('filmname', 'Celebrity'), ('year', '1999-04-08T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q1218888'), ('filmname', 'Love and Death'), ('year', '1975-01-01T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q181555'), ('filmname', 'Crimes and Misdemeanors'), ('year', '1989-01-01T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q181555'), ('filmname', 'Crimes and Misdemeanors'), ('year', '1990-03-01T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q682002'), ('filmname', 'scoop'), ('year', '2006-01-01T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q682002'), ('filmname', 'scoop'), ('year', '2006-11-16T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q653518'), ('filmname', 'Stardust Memories'), ('year', '1980-01-01T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q653518'), ('filmname', 'Stardust Memories'), ('year', '1981-01-22T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q977372'), ('filmname', 'New York Stories'), ('year', '1989-01-01T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q977372'), ('filmname', 'New York Stories'), ('year', '1989-03-10T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q977372'), ('filmname', 'New York Stories'), ('year', '1989-09-21T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q65552643'), ('filmname', "Rifkin's Festival"), ('year', '2020-01-01T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q750003'), ('filmname', 'Sleeper'), ('year', '1973-12-17T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q750003'), ('filmname', 'Sleeper'), ('year', '1974-04-25T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q610163'), ('filmname', 'Small Time Crooks'), ('year', '2000-01-01T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q610163'), ('filmname', 'Small Time Crooks'), ('year', '2000-11-30T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q910523'), ('filmname', 'Shadows and Fog'), ('year', '1991-01-01T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q910523'), ('filmname', 'Shadows and Fog'), ('year', '1992-02-27T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q1133277'), ('filmname', 'Manhattan Murder Mystery'), ('year', '1993-01-01T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q1133277'), ('filmname', 'Manhattan Murder Mystery'), ('year', '1994-02-03T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q1146315'), ('filmname', 'Take the Money and Run'), ('year', '1969-01-01T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q1354121'), ('filmname', 'Melinda and Melinda'), ('year', '2004-01-01T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q1354121'), ('filmname', 'Melinda and Melinda'), ('year', '2005-03-18T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q1354121'), ('filmname', 'Melinda and Melinda'), ('year', '2005-06-23T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q2907178'), ('filmname', 'Blue Jasmine'), ('year', '2013-07-26T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q2907178'), ('filmname', 'Blue Jasmine'), ('year', '2013-08-29T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q2907178'), ('filmname', 'Blue Jasmine'), ('year', '2013-11-07T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q731310'), ('filmname', 'Manhattan'), ('year', '1979-01-01T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q731310'), ('filmname', 'Manhattan'), ('year', '1979-08-30T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q731310'), ('filmname', 'Manhattan'), ('year', '1979-12-14T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q833530'), ('filmname', "Cassandra's Dream"), ('year', '2007-01-01T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q833530'), ('filmname', "Cassandra's Dream"), ('year', '2008-06-05T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q499697'), ('filmname', 'Everything You Always Wanted to Know About Sex*'), ('year', '1972-01-01T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q912729'), ('filmname', 'The Purple Rose of Cairo'), ('year', '1985-01-01T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q912729'), ('filmname', 'The Purple Rose of Cairo'), ('year', '1985-10-03T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q1770003'), ('filmname', 'September'), ('year', '1987-01-01T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q1770003'), ('filmname', 'September'), ('year', '1988-03-31T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q692208'), ('filmname', 'Whatever Works'), ('year', '2009-01-01T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q692208'), ('filmname', 'Whatever Works'), ('year', '2009-12-03T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q17417520'), ('filmname', 'Irrational Man'), ('year', '2015-05-16T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q29658'), ('filmname', 'To Rome with Love'), ('year', '2012-01-01T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q29658'), ('filmname', 'To Rome with Love'), ('year', '2012-08-30T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q20950014'), ('filmname', 'Café Society'), ('year', '2016-01-01T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q20950014'), ('filmname', 'Café Society'), ('year', '2016-11-10T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q20950014'), ('filmname', 'Café Society'), ('year', '2016-11-17T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q1306629'), ('filmname', "A Midsummer Night's Sex Comedy"), ('year', '1982-01-01T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q1306629'), ('filmname', "A Midsummer Night's Sex Comedy"), ('year', '1982-10-15T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q541185'), ('filmname', 'Another Woman'), ('year', '1988-01-01T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q541185'), ('filmname', 'Another Woman'), ('year', '1989-03-16T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q685109'), ('filmname', 'Radio Days'), ('year', '1987-01-01T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q685109'), ('filmname', 'Radio Days'), ('year', '1987-10-01T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q42307699'), ('filmname', 'A Rainy Day in New York'), ('year', '2019-07-26T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q42307699'), ('filmname', 'A Rainy Day in New York'), ('year', '2019-09-18T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q42307699'), ('filmname', 'A Rainy Day in New York'), ('year', '2019-12-05T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q42307699'), ('filmname', 'A Rainy Day in New York'), ('year', '2019-12-12T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q1334572'), ('filmname', 'Everyone Says I Love You'), ('year', '1996-01-01T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q1334572'), ('filmname', 'Everyone Says I Love You'), ('year', '1996-12-08T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q1334572'), ('filmname', 'Everyone Says I Love You'), ('year', '1997-08-14T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q212123'), ('filmname', 'Vicky Cristina Barcelona'), ('year', '2008-01-01T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q212123'), ('filmname', 'Vicky Cristina Barcelona'), ('year', '2008-12-04T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q233464'), ('filmname', 'Annie Hall'), ('year', '1977-04-20T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q335508'), ('filmname', 'The Curse of the Jade Scorpion'), ('year', '2001-01-01T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q335508'), ('filmname', 'The Curse of the Jade Scorpion'), ('year', '2001-12-06T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q551762'), ('filmname', 'Deconstructing Harry'), ('year', '1997-01-01T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q551762'), ('filmname', 'Deconstructing Harry'), ('year', '1998-05-21T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q582021'), ('filmname', 'Hollywood Ending'), ('year', '2002-01-01T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q845057'), ('filmname', 'Hannah and Her Sisters'), ('year', '1986-02-07T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q845057'), ('filmname', 'Hannah and Her Sisters'), ('year', '1986-10-02T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q961403'), ('filmname', 'Interiors'), ('year', '1978-01-01T00:00:00Z')]
# 101

# %%
# write your queries

# Director Number P57
# FILM Q11424
# WOODEY ALLEN Q25089
# SEARCH ALL THE FLIMS WHOSE IS DIRECTED BY WOODEY ALLEN
# LETS FIND PUBLICATON YEAR
# FIND PUBLICATION YEAR OF EACH FILIM

# tRY TO FIND WITH FIRST DATE OF PUBLICATIN 

queryString = """
SELECT DISTINCT ?film ?filmname (YEAR(?date) AS ?publicationYear)
WHERE {
   # bind something
   # ?film wdt:P57 wd:Q25089;
   wdt:P31 wd:Q11424;
   wdt:P577 ?date.
   
   filter NOT EXISTS{
   # ?film wdt:P577 ?secondDate.
   filter(?secondDate < ?date).
   }
   
   
   # get the label
   # ?film sc:name ?filmname.
    
}
LIMIT 50
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('film', 'http://www.wikidata.org/entity/Q3986392'), ('filmname', 'The Concert for New York City'), ('publicationYear', '2001')]
# [('film', 'http://www.wikidata.org/entity/Q206124'), ('filmname', 'Midnight in Paris'), ('publicationYear', '2011')]
# [('film', 'http://www.wikidata.org/entity/Q682262'), ('filmname', 'Alice'), ('publicationYear', '1990')]
# [('film', 'http://www.wikidata.org/entity/Q971865'), ('filmname', "What's Up, Tiger Lily?"), ('publicationYear', '1966')]
# [('film', 'http://www.wikidata.org/entity/Q1004531'), ('filmname', 'Bullets Over Broadway'), ('publicationYear', '1994')]
# [('film', 'http://www.wikidata.org/entity/Q1354109'), ('filmname', 'Mighty Aphrodite'), ('publicationYear', '1995')]
# [('film', 'http://www.wikidata.org/entity/Q729026'), ('filmname', 'Broadway Danny Rose'), ('publicationYear', '1984')]
# [('film', 'http://www.wikidata.org/entity/Q733677'), ('filmname', 'Match Point'), ('publicationYear', '2005')]
# [('film', 'http://www.wikidata.org/entity/Q740143'), ('filmname', 'Husbands and Wives'), ('publicationYear', '1992')]
# [('film', 'http://www.wikidata.org/entity/Q806092'), ('filmname', 'Bananas'), ('publicationYear', '1971')]
# [('film', 'http://www.wikidata.org/entity/Q1321004'), ('filmname', 'You Will Meet a Tall Dark Stranger'), ('publicationYear', '2010')]
# [('film', 'http://www.wikidata.org/entity/Q14511869'), ('filmname', 'Magic in the Moonlight'), ('publicationYear', '2014')]
# [('film', 'http://www.wikidata.org/entity/Q614009'), ('filmname', 'Anything Else'), ('publicationYear', '2003')]
# [('film', 'http://www.wikidata.org/entity/Q187423'), ('filmname', 'Zelig'), ('publicationYear', '1983')]
# [('film', 'http://www.wikidata.org/entity/Q27703144'), ('filmname', 'Wonder Wheel'), ('publicationYear', '2017')]
# [('film', 'http://www.wikidata.org/entity/Q786585'), ('filmname', 'Sweet and Lowdown'), ('publicationYear', '1999')]
# [('film', 'http://www.wikidata.org/entity/Q1052826'), ('filmname', 'Celebrity'), ('publicationYear', '1998')]
# [('film', 'http://www.wikidata.org/entity/Q1218888'), ('filmname', 'Love and Death'), ('publicationYear', '1975')]
# [('film', 'http://www.wikidata.org/entity/Q181555'), ('filmname', 'Crimes and Misdemeanors'), ('publicationYear', '1989')]
# [('film', 'http://www.wikidata.org/entity/Q682002'), ('filmname', 'scoop'), ('publicationYear', '2006')]
# [('film', 'http://www.wikidata.org/entity/Q653518'), ('filmname', 'Stardust Memories'), ('publicationYear', '1980')]
# [('film', 'http://www.wikidata.org/entity/Q977372'), ('filmname', 'New York Stories'), ('publicationYear', '1989')]
# [('film', 'http://www.wikidata.org/entity/Q65552643'), ('filmname', "Rifkin's Festival"), ('publicationYear', '2020')]
# [('film', 'http://www.wikidata.org/entity/Q750003'), ('filmname', 'Sleeper'), ('publicationYear', '1973')]
# [('film', 'http://www.wikidata.org/entity/Q610163'), ('filmname', 'Small Time Crooks'), ('publicationYear', '2000')]
# [('film', 'http://www.wikidata.org/entity/Q910523'), ('filmname', 'Shadows and Fog'), ('publicationYear', '1991')]
# [('film', 'http://www.wikidata.org/entity/Q1133277'), ('filmname', 'Manhattan Murder Mystery'), ('publicationYear', '1993')]
# [('film', 'http://www.wikidata.org/entity/Q1146315'), ('filmname', 'Take the Money and Run'), ('publicationYear', '1969')]
# [('film', 'http://www.wikidata.org/entity/Q1354121'), ('filmname', 'Melinda and Melinda'), ('publicationYear', '2004')]
# [('film', 'http://www.wikidata.org/entity/Q2907178'), ('filmname', 'Blue Jasmine'), ('publicationYear', '2013')]
# [('film', 'http://www.wikidata.org/entity/Q731310'), ('filmname', 'Manhattan'), ('publicationYear', '1979')]
# [('film', 'http://www.wikidata.org/entity/Q833530'), ('filmname', "Cassandra's Dream"), ('publicationYear', '2007')]
# [('film', 'http://www.wikidata.org/entity/Q499697'), ('filmname', 'Everything You Always Wanted to Know About Sex*'), ('publicationYear', '1972')]
# [('film', 'http://www.wikidata.org/entity/Q912729'), ('filmname', 'The Purple Rose of Cairo'), ('publicationYear', '1985')]
# [('film', 'http://www.wikidata.org/entity/Q1770003'), ('filmname', 'September'), ('publicationYear', '1987')]
# [('film', 'http://www.wikidata.org/entity/Q692208'), ('filmname', 'Whatever Works'), ('publicationYear', '2009')]
# [('film', 'http://www.wikidata.org/entity/Q17417520'), ('filmname', 'Irrational Man'), ('publicationYear', '2015')]
# [('film', 'http://www.wikidata.org/entity/Q29658'), ('filmname', 'To Rome with Love'), ('publicationYear', '2012')]
# [('film', 'http://www.wikidata.org/entity/Q20950014'), ('filmname', 'Café Society'), ('publicationYear', '2016')]
# [('film', 'http://www.wikidata.org/entity/Q1306629'), ('filmname', "A Midsummer Night's Sex Comedy"), ('publicationYear', '1982')]
# [('film', 'http://www.wikidata.org/entity/Q541185'), ('filmname', 'Another Woman'), ('publicationYear', '1988')]
# [('film', 'http://www.wikidata.org/entity/Q685109'), ('filmname', 'Radio Days'), ('publicationYear', '1987')]
# [('film', 'http://www.wikidata.org/entity/Q42307699'), ('filmname', 'A Rainy Day in New York'), ('publicationYear', '2019')]
# [('film', 'http://www.wikidata.org/entity/Q1334572'), ('filmname', 'Everyone Says I Love You'), ('publicationYear', '1996')]
# [('film', 'http://www.wikidata.org/entity/Q212123'), ('filmname', 'Vicky Cristina Barcelona'), ('publicationYear', '2008')]
# [('film', 'http://www.wikidata.org/entity/Q233464'), ('filmname', 'Annie Hall'), ('publicationYear', '1977')]
# [('film', 'http://www.wikidata.org/entity/Q335508'), ('filmname', 'The Curse of the Jade Scorpion'), ('publicationYear', '2001')]
# [('film', 'http://www.wikidata.org/entity/Q551762'), ('filmname', 'Deconstructing Harry'), ('publicationYear', '1997')]
# [('film', 'http://www.wikidata.org/entity/Q582021'), ('filmname', 'Hollywood Ending'), ('publicationYear', '2002')]
# [('film', 'http://www.wikidata.org/entity/Q845057'), ('filmname', 'Hannah and Her Sisters'), ('publicationYear', '1986')]
# 50

# %%
# write your queries

# Director Number P57
# FILM Q11424
# WOODEY ALLEN Q25089
# SEARCH ALL THE FLIMS WHOSE IS DIRECTED BY WOODEY ALLEN
# LETS FIND PUBLICATON YEAR
# FIND PUBLICATION YEAR OF EACH FILIM

# tRY TO FIND WITH FIRST DATE OF PUBLICATion

queryString = """
SELECT DISTINCT ?film ?filmname (YEAR(?date) AS ?publicationYear)
WHERE {
   # bind something
   # ?film wdt:P57 wd:Q25089;
   wdt:P31 wd:Q11424;
   wdt:P577 ?date.
   
     
   
   # get the label
   # ?film sc:name ?filmname.
    
}
LIMIT 50
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('film', 'http://www.wikidata.org/entity/Q3986392'), ('filmname', 'The Concert for New York City'), ('publicationYear', '2001')]
# [('film', 'http://www.wikidata.org/entity/Q206124'), ('filmname', 'Midnight in Paris'), ('publicationYear', '2011')]
# [('film', 'http://www.wikidata.org/entity/Q682262'), ('filmname', 'Alice'), ('publicationYear', '1990')]
# [('film', 'http://www.wikidata.org/entity/Q682262'), ('filmname', 'Alice'), ('publicationYear', '1991')]
# [('film', 'http://www.wikidata.org/entity/Q971865'), ('filmname', "What's Up, Tiger Lily?"), ('publicationYear', '1966')]
# [('film', 'http://www.wikidata.org/entity/Q1004531'), ('filmname', 'Bullets Over Broadway'), ('publicationYear', '1994')]
# [('film', 'http://www.wikidata.org/entity/Q1004531'), ('filmname', 'Bullets Over Broadway'), ('publicationYear', '1995')]
# [('film', 'http://www.wikidata.org/entity/Q1354109'), ('filmname', 'Mighty Aphrodite'), ('publicationYear', '1995')]
# [('film', 'http://www.wikidata.org/entity/Q1354109'), ('filmname', 'Mighty Aphrodite'), ('publicationYear', '1996')]
# [('film', 'http://www.wikidata.org/entity/Q729026'), ('filmname', 'Broadway Danny Rose'), ('publicationYear', '1984')]
# [('film', 'http://www.wikidata.org/entity/Q733677'), ('filmname', 'Match Point'), ('publicationYear', '2005')]
# [('film', 'http://www.wikidata.org/entity/Q740143'), ('filmname', 'Husbands and Wives'), ('publicationYear', '1992')]
# [('film', 'http://www.wikidata.org/entity/Q740143'), ('filmname', 'Husbands and Wives'), ('publicationYear', '1993')]
# [('film', 'http://www.wikidata.org/entity/Q806092'), ('filmname', 'Bananas'), ('publicationYear', '1971')]
# [('film', 'http://www.wikidata.org/entity/Q806092'), ('filmname', 'Bananas'), ('publicationYear', '1974')]
# [('film', 'http://www.wikidata.org/entity/Q1321004'), ('filmname', 'You Will Meet a Tall Dark Stranger'), ('publicationYear', '2010')]
# [('film', 'http://www.wikidata.org/entity/Q14511869'), ('filmname', 'Magic in the Moonlight'), ('publicationYear', '2014')]
# [('film', 'http://www.wikidata.org/entity/Q614009'), ('filmname', 'Anything Else'), ('publicationYear', '2003')]
# [('film', 'http://www.wikidata.org/entity/Q187423'), ('filmname', 'Zelig'), ('publicationYear', '1983')]
# [('film', 'http://www.wikidata.org/entity/Q27703144'), ('filmname', 'Wonder Wheel'), ('publicationYear', '2017')]
# [('film', 'http://www.wikidata.org/entity/Q27703144'), ('filmname', 'Wonder Wheel'), ('publicationYear', '2018')]
# [('film', 'http://www.wikidata.org/entity/Q786585'), ('filmname', 'Sweet and Lowdown'), ('publicationYear', '1999')]
# [('film', 'http://www.wikidata.org/entity/Q786585'), ('filmname', 'Sweet and Lowdown'), ('publicationYear', '2000')]
# [('film', 'http://www.wikidata.org/entity/Q1052826'), ('filmname', 'Celebrity'), ('publicationYear', '1998')]
# [('film', 'http://www.wikidata.org/entity/Q1052826'), ('filmname', 'Celebrity'), ('publicationYear', '1999')]
# [('film', 'http://www.wikidata.org/entity/Q1218888'), ('filmname', 'Love and Death'), ('publicationYear', '1975')]
# [('film', 'http://www.wikidata.org/entity/Q181555'), ('filmname', 'Crimes and Misdemeanors'), ('publicationYear', '1989')]
# [('film', 'http://www.wikidata.org/entity/Q181555'), ('filmname', 'Crimes and Misdemeanors'), ('publicationYear', '1990')]
# [('film', 'http://www.wikidata.org/entity/Q682002'), ('filmname', 'scoop'), ('publicationYear', '2006')]
# [('film', 'http://www.wikidata.org/entity/Q653518'), ('filmname', 'Stardust Memories'), ('publicationYear', '1980')]
# [('film', 'http://www.wikidata.org/entity/Q653518'), ('filmname', 'Stardust Memories'), ('publicationYear', '1981')]
# [('film', 'http://www.wikidata.org/entity/Q977372'), ('filmname', 'New York Stories'), ('publicationYear', '1989')]
# [('film', 'http://www.wikidata.org/entity/Q65552643'), ('filmname', "Rifkin's Festival"), ('publicationYear', '2020')]
# [('film', 'http://www.wikidata.org/entity/Q750003'), ('filmname', 'Sleeper'), ('publicationYear', '1973')]
# [('film', 'http://www.wikidata.org/entity/Q750003'), ('filmname', 'Sleeper'), ('publicationYear', '1974')]
# [('film', 'http://www.wikidata.org/entity/Q610163'), ('filmname', 'Small Time Crooks'), ('publicationYear', '2000')]
# [('film', 'http://www.wikidata.org/entity/Q910523'), ('filmname', 'Shadows and Fog'), ('publicationYear', '1991')]
# [('film', 'http://www.wikidata.org/entity/Q910523'), ('filmname', 'Shadows and Fog'), ('publicationYear', '1992')]
# [('film', 'http://www.wikidata.org/entity/Q1133277'), ('filmname', 'Manhattan Murder Mystery'), ('publicationYear', '1993')]
# [('film', 'http://www.wikidata.org/entity/Q1133277'), ('filmname', 'Manhattan Murder Mystery'), ('publicationYear', '1994')]
# [('film', 'http://www.wikidata.org/entity/Q1146315'), ('filmname', 'Take the Money and Run'), ('publicationYear', '1969')]
# [('film', 'http://www.wikidata.org/entity/Q1354121'), ('filmname', 'Melinda and Melinda'), ('publicationYear', '2004')]
# [('film', 'http://www.wikidata.org/entity/Q1354121'), ('filmname', 'Melinda and Melinda'), ('publicationYear', '2005')]
# [('film', 'http://www.wikidata.org/entity/Q2907178'), ('filmname', 'Blue Jasmine'), ('publicationYear', '2013')]
# [('film', 'http://www.wikidata.org/entity/Q731310'), ('filmname', 'Manhattan'), ('publicationYear', '1979')]
# [('film', 'http://www.wikidata.org/entity/Q833530'), ('filmname', "Cassandra's Dream"), ('publicationYear', '2007')]
# [('film', 'http://www.wikidata.org/entity/Q833530'), ('filmname', "Cassandra's Dream"), ('publicationYear', '2008')]
# [('film', 'http://www.wikidata.org/entity/Q499697'), ('filmname', 'Everything You Always Wanted to Know About Sex*'), ('publicationYear', '1972')]
# [('film', 'http://www.wikidata.org/entity/Q912729'), ('filmname', 'The Purple Rose of Cairo'), ('publicationYear', '1985')]
# [('film', 'http://www.wikidata.org/entity/Q1770003'), ('filmname', 'September'), ('publicationYear', '1987')]
# 50

# %%
# write your queries

# Director Number P57
# FILM Q11424
# WOODEY ALLEN Q25089
# SEARCH ALL THE FLIMS WHOSE IS DIRECTED BY WOODEY ALLEN
# LETS FIND PUBLICATON YEAR
# FIND PUBLICATION YEAR OF EACH FILIM

# tRY TO FIND WITH FIRST DATE OF PUBLICATion

queryString = """
SELECT DISTINCT ?film ?filmname (YEAR(?date) AS ?publicationYear) (count(?film) AS ?numFilms)
WHERE {
   # bind something
   # ?film wdt:P57 wd:Q25089;
   wdt:P31 wd:Q11424;
   wdt:P577 ?date.
   
 
   filter NOT EXISTS{
   # ?film wdt:P577 ?secondDate.
   filter(?secondDate < ?date).
   }
   
   # get the label
   # ?film sc:name ?filmname.
    
}
LIMIT 50
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('film', 'http://www.wikidata.org/entity/Q206124'), ('filmname', 'Midnight in Paris'), ('publicationYear', '2011'), ('numFilms', '1')]
# [('film', 'http://www.wikidata.org/entity/Q806092'), ('filmname', 'Bananas'), ('publicationYear', '1971'), ('numFilms', '1')]
# [('film', 'http://www.wikidata.org/entity/Q187423'), ('filmname', 'Zelig'), ('publicationYear', '1983'), ('numFilms', '1')]
# [('film', 'http://www.wikidata.org/entity/Q3986392'), ('filmname', 'The Concert for New York City'), ('publicationYear', '2001'), ('numFilms', '1')]
# [('film', 'http://www.wikidata.org/entity/Q682262'), ('filmname', 'Alice'), ('publicationYear', '1990'), ('numFilms', '1')]
# [('film', 'http://www.wikidata.org/entity/Q614009'), ('filmname', 'Anything Else'), ('publicationYear', '2003'), ('numFilms', '1')]
# [('film', 'http://www.wikidata.org/entity/Q910523'), ('filmname', 'Shadows and Fog'), ('publicationYear', '1991'), ('numFilms', '1')]
# [('film', 'http://www.wikidata.org/entity/Q1133277'), ('filmname', 'Manhattan Murder Mystery'), ('publicationYear', '1993'), ('numFilms', '1')]
# [('film', 'http://www.wikidata.org/entity/Q1770003'), ('filmname', 'September'), ('publicationYear', '1987'), ('numFilms', '1')]
# [('film', 'http://www.wikidata.org/entity/Q1306629'), ('filmname', "A Midsummer Night's Sex Comedy"), ('publicationYear', '1982'), ('numFilms', '1')]
# [('film', 'http://www.wikidata.org/entity/Q1334572'), ('filmname', 'Everyone Says I Love You'), ('publicationYear', '1996'), ('numFilms', '1')]
# [('film', 'http://www.wikidata.org/entity/Q233464'), ('filmname', 'Annie Hall'), ('publicationYear', '1977'), ('numFilms', '1')]
# [('film', 'http://www.wikidata.org/entity/Q551762'), ('filmname', 'Deconstructing Harry'), ('publicationYear', '1997'), ('numFilms', '1')]
# [('film', 'http://www.wikidata.org/entity/Q1354109'), ('filmname', 'Mighty Aphrodite'), ('publicationYear', '1995'), ('numFilms', '1')]
# [('film', 'http://www.wikidata.org/entity/Q729026'), ('filmname', 'Broadway Danny Rose'), ('publicationYear', '1984'), ('numFilms', '1')]
# [('film', 'http://www.wikidata.org/entity/Q582021'), ('filmname', 'Hollywood Ending'), ('publicationYear', '2002'), ('numFilms', '1')]
# [('film', 'http://www.wikidata.org/entity/Q65552643'), ('filmname', "Rifkin's Festival"), ('publicationYear', '2020'), ('numFilms', '1')]
# [('film', 'http://www.wikidata.org/entity/Q27703144'), ('filmname', 'Wonder Wheel'), ('publicationYear', '2017'), ('numFilms', '1')]
# [('film', 'http://www.wikidata.org/entity/Q682002'), ('filmname', 'scoop'), ('publicationYear', '2006'), ('numFilms', '1')]
# [('film', 'http://www.wikidata.org/entity/Q20950014'), ('filmname', 'Café Society'), ('publicationYear', '2016'), ('numFilms', '1')]
# [('film', 'http://www.wikidata.org/entity/Q845057'), ('filmname', 'Hannah and Her Sisters'), ('publicationYear', '1986'), ('numFilms', '1')]
# [('film', 'http://www.wikidata.org/entity/Q733677'), ('filmname', 'Match Point'), ('publicationYear', '2005'), ('numFilms', '1')]
# [('film', 'http://www.wikidata.org/entity/Q1218888'), ('filmname', 'Love and Death'), ('publicationYear', '1975'), ('numFilms', '1')]
# [('film', 'http://www.wikidata.org/entity/Q731310'), ('filmname', 'Manhattan'), ('publicationYear', '1979'), ('numFilms', '1')]
# [('film', 'http://www.wikidata.org/entity/Q335508'), ('filmname', 'The Curse of the Jade Scorpion'), ('publicationYear', '2001'), ('numFilms', '1')]
# [('film', 'http://www.wikidata.org/entity/Q181555'), ('filmname', 'Crimes and Misdemeanors'), ('publicationYear', '1989'), ('numFilms', '1')]
# [('film', 'http://www.wikidata.org/entity/Q977372'), ('filmname', 'New York Stories'), ('publicationYear', '1989'), ('numFilms', '1')]
# [('film', 'http://www.wikidata.org/entity/Q17417520'), ('filmname', 'Irrational Man'), ('publicationYear', '2015'), ('numFilms', '1')]
# [('film', 'http://www.wikidata.org/entity/Q685109'), ('filmname', 'Radio Days'), ('publicationYear', '1987'), ('numFilms', '1')]
# [('film', 'http://www.wikidata.org/entity/Q750003'), ('filmname', 'Sleeper'), ('publicationYear', '1973'), ('numFilms', '1')]
# [('film', 'http://www.wikidata.org/entity/Q1146315'), ('filmname', 'Take the Money and Run'), ('publicationYear', '1969'), ('numFilms', '1')]
# [('film', 'http://www.wikidata.org/entity/Q2907178'), ('filmname', 'Blue Jasmine'), ('publicationYear', '2013'), ('numFilms', '1')]
# [('film', 'http://www.wikidata.org/entity/Q833530'), ('filmname', "Cassandra's Dream"), ('publicationYear', '2007'), ('numFilms', '1')]
# [('film', 'http://www.wikidata.org/entity/Q29658'), ('filmname', 'To Rome with Love'), ('publicationYear', '2012'), ('numFilms', '1')]
# [('film', 'http://www.wikidata.org/entity/Q971865'), ('filmname', "What's Up, Tiger Lily?"), ('publicationYear', '1966'), ('numFilms', '1')]
# [('film', 'http://www.wikidata.org/entity/Q14511869'), ('filmname', 'Magic in the Moonlight'), ('publicationYear', '2014'), ('numFilms', '1')]
# [('film', 'http://www.wikidata.org/entity/Q1052826'), ('filmname', 'Celebrity'), ('publicationYear', '1998'), ('numFilms', '1')]
# [('film', 'http://www.wikidata.org/entity/Q499697'), ('filmname', 'Everything You Always Wanted to Know About Sex*'), ('publicationYear', '1972'), ('numFilms', '1')]
# [('film', 'http://www.wikidata.org/entity/Q692208'), ('filmname', 'Whatever Works'), ('publicationYear', '2009'), ('numFilms', '1')]
# [('film', 'http://www.wikidata.org/entity/Q541185'), ('filmname', 'Another Woman'), ('publicationYear', '1988'), ('numFilms', '1')]
# [('film', 'http://www.wikidata.org/entity/Q42307699'), ('filmname', 'A Rainy Day in New York'), ('publicationYear', '2019'), ('numFilms', '1')]
# [('film', 'http://www.wikidata.org/entity/Q212123'), ('filmname', 'Vicky Cristina Barcelona'), ('publicationYear', '2008'), ('numFilms', '1')]
# [('film', 'http://www.wikidata.org/entity/Q740143'), ('filmname', 'Husbands and Wives'), ('publicationYear', '1992'), ('numFilms', '1')]
# [('film', 'http://www.wikidata.org/entity/Q786585'), ('filmname', 'Sweet and Lowdown'), ('publicationYear', '1999'), ('numFilms', '1')]
# [('film', 'http://www.wikidata.org/entity/Q912729'), ('filmname', 'The Purple Rose of Cairo'), ('publicationYear', '1985'), ('numFilms', '1')]
# [('film', 'http://www.wikidata.org/entity/Q961403'), ('filmname', 'Interiors'), ('publicationYear', '1978'), ('numFilms', '1')]
# [('film', 'http://www.wikidata.org/entity/Q1004531'), ('filmname', 'Bullets Over Broadway'), ('publicationYear', '1994'), ('numFilms', '1')]
# [('film', 'http://www.wikidata.org/entity/Q1321004'), ('filmname', 'You Will Meet a Tall Dark Stranger'), ('publicationYear', '2010'), ('numFilms', '1')]
# [('film', 'http://www.wikidata.org/entity/Q653518'), ('filmname', 'Stardust Memories'), ('publicationYear', '1980'), ('numFilms', '1')]
# [('film', 'http://www.wikidata.org/entity/Q610163'), ('filmname', 'Small Time Crooks'), ('publicationYear', '2000'), ('numFilms', '1')]
# 50

# %%
# write your queries

# Director Number P57
# FILM Q11424
# WOODEY ALLEN Q25089
# SEARCH ALL THE FLIMS WHOSE IS DIRECTED BY WOODEY ALLEN
# LETS FIND PUBLICATON YEAR
# FIND PUBLICATION YEAR OF EACH FILIM

# tRY TO FIND WITH FIRST DATE OF PUBLICATion

queryString = """
SELECT DISTINCT ?film ?filmname (YEAR(?date) AS ?publicationYear) (count(?film) AS ?numFilms)
WHERE {
   # bind something
   # ?film wdt:P57 wd:Q25089;
   wdt:P31 wd:Q11424;
   wdt:P577 ?date.
   
 
   filter NOT EXISTS{
   # ?film wdt:P577 ?secondDate.
   filter(?secondDate < ?date).
   }
   
   # get the label
   # ?film sc:name ?filmname.
    
}
LIMIT 50
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('film', 'http://www.wikidata.org/entity/Q206124'), ('filmname', 'Midnight in Paris'), ('publicationYear', '2011'), ('numFilms', '1')]
# [('film', 'http://www.wikidata.org/entity/Q806092'), ('filmname', 'Bananas'), ('publicationYear', '1971'), ('numFilms', '1')]
# [('film', 'http://www.wikidata.org/entity/Q187423'), ('filmname', 'Zelig'), ('publicationYear', '1983'), ('numFilms', '1')]
# [('film', 'http://www.wikidata.org/entity/Q3986392'), ('filmname', 'The Concert for New York City'), ('publicationYear', '2001'), ('numFilms', '1')]
# [('film', 'http://www.wikidata.org/entity/Q682262'), ('filmname', 'Alice'), ('publicationYear', '1990'), ('numFilms', '1')]
# [('film', 'http://www.wikidata.org/entity/Q614009'), ('filmname', 'Anything Else'), ('publicationYear', '2003'), ('numFilms', '1')]
# [('film', 'http://www.wikidata.org/entity/Q910523'), ('filmname', 'Shadows and Fog'), ('publicationYear', '1991'), ('numFilms', '1')]
# [('film', 'http://www.wikidata.org/entity/Q1133277'), ('filmname', 'Manhattan Murder Mystery'), ('publicationYear', '1993'), ('numFilms', '1')]
# [('film', 'http://www.wikidata.org/entity/Q1770003'), ('filmname', 'September'), ('publicationYear', '1987'), ('numFilms', '1')]
# [('film', 'http://www.wikidata.org/entity/Q1306629'), ('filmname', "A Midsummer Night's Sex Comedy"), ('publicationYear', '1982'), ('numFilms', '1')]
# [('film', 'http://www.wikidata.org/entity/Q1334572'), ('filmname', 'Everyone Says I Love You'), ('publicationYear', '1996'), ('numFilms', '1')]
# [('film', 'http://www.wikidata.org/entity/Q233464'), ('filmname', 'Annie Hall'), ('publicationYear', '1977'), ('numFilms', '1')]
# [('film', 'http://www.wikidata.org/entity/Q551762'), ('filmname', 'Deconstructing Harry'), ('publicationYear', '1997'), ('numFilms', '1')]
# [('film', 'http://www.wikidata.org/entity/Q1354109'), ('filmname', 'Mighty Aphrodite'), ('publicationYear', '1995'), ('numFilms', '1')]
# [('film', 'http://www.wikidata.org/entity/Q729026'), ('filmname', 'Broadway Danny Rose'), ('publicationYear', '1984'), ('numFilms', '1')]
# [('film', 'http://www.wikidata.org/entity/Q582021'), ('filmname', 'Hollywood Ending'), ('publicationYear', '2002'), ('numFilms', '1')]
# [('film', 'http://www.wikidata.org/entity/Q65552643'), ('filmname', "Rifkin's Festival"), ('publicationYear', '2020'), ('numFilms', '1')]
# [('film', 'http://www.wikidata.org/entity/Q27703144'), ('filmname', 'Wonder Wheel'), ('publicationYear', '2017'), ('numFilms', '1')]
# [('film', 'http://www.wikidata.org/entity/Q682002'), ('filmname', 'scoop'), ('publicationYear', '2006'), ('numFilms', '1')]
# [('film', 'http://www.wikidata.org/entity/Q20950014'), ('filmname', 'Café Society'), ('publicationYear', '2016'), ('numFilms', '1')]
# [('film', 'http://www.wikidata.org/entity/Q845057'), ('filmname', 'Hannah and Her Sisters'), ('publicationYear', '1986'), ('numFilms', '1')]
# [('film', 'http://www.wikidata.org/entity/Q733677'), ('filmname', 'Match Point'), ('publicationYear', '2005'), ('numFilms', '1')]
# [('film', 'http://www.wikidata.org/entity/Q1218888'), ('filmname', 'Love and Death'), ('publicationYear', '1975'), ('numFilms', '1')]
# [('film', 'http://www.wikidata.org/entity/Q731310'), ('filmname', 'Manhattan'), ('publicationYear', '1979'), ('numFilms', '1')]
# [('film', 'http://www.wikidata.org/entity/Q335508'), ('filmname', 'The Curse of the Jade Scorpion'), ('publicationYear', '2001'), ('numFilms', '1')]
# [('film', 'http://www.wikidata.org/entity/Q181555'), ('filmname', 'Crimes and Misdemeanors'), ('publicationYear', '1989'), ('numFilms', '1')]
# [('film', 'http://www.wikidata.org/entity/Q977372'), ('filmname', 'New York Stories'), ('publicationYear', '1989'), ('numFilms', '1')]
# [('film', 'http://www.wikidata.org/entity/Q17417520'), ('filmname', 'Irrational Man'), ('publicationYear', '2015'), ('numFilms', '1')]
# [('film', 'http://www.wikidata.org/entity/Q685109'), ('filmname', 'Radio Days'), ('publicationYear', '1987'), ('numFilms', '1')]
# [('film', 'http://www.wikidata.org/entity/Q750003'), ('filmname', 'Sleeper'), ('publicationYear', '1973'), ('numFilms', '1')]
# [('film', 'http://www.wikidata.org/entity/Q1146315'), ('filmname', 'Take the Money and Run'), ('publicationYear', '1969'), ('numFilms', '1')]
# [('film', 'http://www.wikidata.org/entity/Q2907178'), ('filmname', 'Blue Jasmine'), ('publicationYear', '2013'), ('numFilms', '1')]
# [('film', 'http://www.wikidata.org/entity/Q833530'), ('filmname', "Cassandra's Dream"), ('publicationYear', '2007'), ('numFilms', '1')]
# [('film', 'http://www.wikidata.org/entity/Q29658'), ('filmname', 'To Rome with Love'), ('publicationYear', '2012'), ('numFilms', '1')]
# [('film', 'http://www.wikidata.org/entity/Q971865'), ('filmname', "What's Up, Tiger Lily?"), ('publicationYear', '1966'), ('numFilms', '1')]
# [('film', 'http://www.wikidata.org/entity/Q14511869'), ('filmname', 'Magic in the Moonlight'), ('publicationYear', '2014'), ('numFilms', '1')]
# [('film', 'http://www.wikidata.org/entity/Q1052826'), ('filmname', 'Celebrity'), ('publicationYear', '1998'), ('numFilms', '1')]
# [('film', 'http://www.wikidata.org/entity/Q499697'), ('filmname', 'Everything You Always Wanted to Know About Sex*'), ('publicationYear', '1972'), ('numFilms', '1')]
# [('film', 'http://www.wikidata.org/entity/Q692208'), ('filmname', 'Whatever Works'), ('publicationYear', '2009'), ('numFilms', '1')]
# [('film', 'http://www.wikidata.org/entity/Q541185'), ('filmname', 'Another Woman'), ('publicationYear', '1988'), ('numFilms', '1')]
# [('film', 'http://www.wikidata.org/entity/Q42307699'), ('filmname', 'A Rainy Day in New York'), ('publicationYear', '2019'), ('numFilms', '1')]
# [('film', 'http://www.wikidata.org/entity/Q212123'), ('filmname', 'Vicky Cristina Barcelona'), ('publicationYear', '2008'), ('numFilms', '1')]
# [('film', 'http://www.wikidata.org/entity/Q740143'), ('filmname', 'Husbands and Wives'), ('publicationYear', '1992'), ('numFilms', '1')]
# [('film', 'http://www.wikidata.org/entity/Q786585'), ('filmname', 'Sweet and Lowdown'), ('publicationYear', '1999'), ('numFilms', '1')]
# [('film', 'http://www.wikidata.org/entity/Q912729'), ('filmname', 'The Purple Rose of Cairo'), ('publicationYear', '1985'), ('numFilms', '1')]
# [('film', 'http://www.wikidata.org/entity/Q961403'), ('filmname', 'Interiors'), ('publicationYear', '1978'), ('numFilms', '1')]
# [('film', 'http://www.wikidata.org/entity/Q1004531'), ('filmname', 'Bullets Over Broadway'), ('publicationYear', '1994'), ('numFilms', '1')]
# [('film', 'http://www.wikidata.org/entity/Q1321004'), ('filmname', 'You Will Meet a Tall Dark Stranger'), ('publicationYear', '2010'), ('numFilms', '1')]
# [('film', 'http://www.wikidata.org/entity/Q653518'), ('filmname', 'Stardust Memories'), ('publicationYear', '1980'), ('numFilms', '1')]
# [('film', 'http://www.wikidata.org/entity/Q610163'), ('filmname', 'Small Time Crooks'), ('publicationYear', '2000'), ('numFilms', '1')]
# 50

# %% [markdown]
# Final query for this task

# %%
# write your final query
# write your queries

# Director Number P57
# FILM Q11424
# WOODEY ALLEN Q25089
# SEARCH ALL THE FLIMS WHOSE IS DIRECTED BY WOODEY ALLEN
# LETS FIND PUBLICATON YEAR
# FIND PUBLICATION YEAR OF EACH FILIM

# tRY TO FIND WITH FIRST DATE OF PUBLICATion

queryString = """
SELECT DISTINCT ?dir ?dirName (YEAR(?date) AS ?publicationYear) (count(?film) AS ?numFilms)
WHERE {
   # bind something
   # ?film wdt:P57 dir;
   wdt:P31 wd:Q11424;
   wdt:P577 ?date.
   
   # ?dir sc:name ?dirName
   FILTER(?dir=wd:Q25089 || ?dir=wd:Q3772)
   
   
 
   filter NOT EXISTS{
   # ?film wdt:P577 ?secondDate.
   filter(?secondDate < ?date).
   }
   
   # get the label
   # ?film sc:name ?filmname.
    
}
LIMIT 50
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# The operation failed QueryBadFormed: a bad request has been sent to the endpoint, probably the sparql query is bad formed.
#
# Response:
# b"Virtuoso 37000 Error SP030: SPARQL compiler, line 13: syntax error at 'dir' before ';'\n\nSPARQL query:\ndefine sql:big-data-const 0\n#output-format:application/sparql-results+json\n\n##-4ddda0dbce-##\nPREFIX wd: <http://www.wikidata.org/entity/> \nPREFIX wdt: <http://www.wikidata.org/prop/direct/> \nPREFIX sc: <http://schema.org/>\n\n\nSELECT DISTINCT ?dir ?dirName (YEAR(?date) AS ?publicationYear) (count(?film) AS ?numFilms)\nWHERE {\n   # bind something\n   ?film wdt:P57 dir;\n   wdt:P31 wd:Q11424;\n   wdt:P577 ?date.\n   \n   ?dir sc:name ?dirName\n   FILTER(?dir=wd:Q25089 || ?dir=wd:Q3772)\n   \n   \n \n   filter NOT EXISTS{\n   ?film wdt:P577 ?secondDate.\n   filter(?secondDate < ?date).\n   }\n   \n   # get the label\n   ?film sc:name ?filmname.\n    \n}\nLIMIT 50\n"

# %% [markdown]
# ## Task 6
# Identify the BGP for Academy Awards

# %%
# write your queries

queryString = """
SELECT DISTINCT ?object ?name
WHERE {
    #BIND SOMETHING
    wd:Q3772 ?p ?object.
    # get the label
    # ?object sc:name ?name
    
    
}

LIMIT 100
"""

print("Result")
x=run_query(queryString)
# Out:
# Result
# [('object', 'http://www.wikidata.org/entity/Q212026'), ('name', 'Mira Sorvino')]
# [('object', 'http://www.wikidata.org/entity/Q2566554'), ('name', '48th British Academy Film Awards')]
# [('object', 'http://www.wikidata.org/entity/Q833154'), ('name', 'Edgar Awards')]
# [('object', 'http://www.wikidata.org/entity/Q103360'), ('name', 'Academy Award for Best Director')]
# [('object', 'http://www.wikidata.org/entity/Q10798782'), ('name', 'television actor')]
# [('object', 'http://www.wikidata.org/entity/Q10800557'), ('name', 'film actor')]
# [('object', 'http://www.wikidata.org/entity/Q113068'), ('name', 'Hungarian Order of Merit')]
# [('object', 'http://www.wikidata.org/entity/Q13452531'), ('name', 'Commandeur des Arts et des Lettres\u200e')]
# [('object', 'http://www.wikidata.org/entity/Q17290934'), ('name', 'Lentapedia')]
# [('object', 'http://www.wikidata.org/entity/Q179808'), ('name', "Palme d'Or")]
# [('object', 'http://www.wikidata.org/entity/Q17985761'), ('name', 'star on Hollywood Walk of Fame')]
# [('object', 'http://www.wikidata.org/entity/Q1860'), ('name', 'English')]
# [('object', 'http://www.wikidata.org/entity/Q188'), ('name', 'German')]
# [('object', 'http://www.wikidata.org/entity/Q188473'), ('name', 'action film')]
# [('object', 'http://www.wikidata.org/entity/Q188740'), ('name', 'Museum of Modern Art')]
# [('object', 'http://www.wikidata.org/entity/Q2526255'), ('name', 'film director')]
# [('object', 'http://www.wikidata.org/entity/Q28389'), ('name', 'screenwriter')]
# [('object', 'http://www.wikidata.org/entity/Q30'), ('name', 'United States of America')]
# [('object', 'http://www.wikidata.org/entity/Q3282637'), ('name', 'film producer')]
# [('object', 'http://www.wikidata.org/entity/Q33999'), ('name', 'actor')]
# [('object', 'http://www.wikidata.org/entity/Q3455803'), ('name', 'director')]
# [('object', 'http://www.wikidata.org/entity/Q36180'), ('name', 'writer')]
# [('object', 'http://www.wikidata.org/entity/Q41417'), ('name', 'Academy Award for Best Writing, Original Screenplay')]
# [('object', 'http://www.wikidata.org/entity/Q463303'), ('name', 'American Academy of Arts and Sciences')]
# [('object', 'http://www.wikidata.org/entity/Q490861'), ('name', '70th Golden Globe Awards')]
# [('object', 'http://www.wikidata.org/entity/Q5'), ('name', 'human')]
# [('object', 'http://www.wikidata.org/entity/Q5043'), ('name', 'Christianity')]
# [('object', 'http://www.wikidata.org/entity/Q52382875'), ('name', 'AAAS Fellow')]
# [('object', 'http://www.wikidata.org/entity/Q6581097'), ('name', 'male')]
# [('object', 'http://www.wikidata.org/entity/Q67311526'), ('name', 'Obalky knih.cz')]
# [('object', 'http://www.wikidata.org/entity/Q7042855'), ('name', 'film editor')]
# [('object', 'http://www.wikidata.org/entity/Q73555012'), ('name', 'works protected by copyrights')]
# [('object', 'http://www.wikidata.org/entity/Q1377772'), ('name', 'European Film Award for Best Non-European Film')]
# [('object', 'http://www.wikidata.org/entity/Q1789102'), ('name', 'National Board of Review Award for Best Film')]
# [('object', 'http://www.wikidata.org/entity/Q23958341'), ('name', 'President of the Jury at the Cannes Festival')]
# [('object', 'http://www.wikidata.org/entity/Q974693'), ('name', 'Italian American')]
# [('object', 'http://www.wikidata.org/entity/Q1075293'), ('name', 'Irish Americans')]
# [('object', 'http://www.wikidata.org/entity/Q185582'), ('name', 'Knoxville')]
# [('object', 'http://www.wikidata.org/entity/Q51581'), ('name', 'Howard Hawks')]
# [('object', 'http://www.wikidata.org/entity/Q41375'), ('name', 'BAFTA Award for Best Original Screenplay')]
# [('object', 'http://www.wikidata.org/entity/Q849124'), ('name', 'Golden Globe Award for Best Screenplay')]
# [('object', 'http://www.wikidata.org/entity/Q93439'), ('name', '52nd Golden Globe Awards')]
# [('object', 'http://www.wikidata.org/entity/Q459290'), ('name', 'independent film')]
# [('object', 'http://www.wikidata.org/entity/Q1158484'), ('name', 'Quentin')]
# [('object', 'http://www.wikidata.org/entity/Q21487819'), ('name', 'Tarantino')]
# [('object', 'http://www.wikidata.org/entity/Q3404975'), ('name', 'Lumière Award, Lyon Festival of cinema')]
# [('object', 'http://www.wikidata.org/entity/Q245949'), ('name', '36th César Awards')]
# [('object', 'http://www.wikidata.org/entity/Q32947601'), ('name', 'Daniella Pick')]
# [('object', 'http://www.wikidata.org/entity/Q2690424'), ('name', '66th British Academy Film Awards')]
# [('object', 'http://www.wikidata.org/entity/Q5274115'), ('name', 'Didem Erol')]
# [('object', 'http://www.wikidata.org/entity/Q4818309'), ('name', 'Tony Tarantino')]
# [('object', 'http://www.wikidata.org/entity/Q6489997'), ('name', 'Template:Quentin Tarantino')]
# [('object', 'http://www.wikidata.org/entity/Q6838938'), ('name', 'Category:Films directed by Quentin Tarantino')]
# [('object', 'http://www.wikidata.org/entity/Q10113292'), ('name', 'Category:Quentin Tarantino')]
# [('object', 'http://www.wikidata.org/entity/Q6794012'), ('name', 'Quentin Tarantino filmography')]
# [('object', 'http://www.wikidata.org/entity/Q7005534'), ('name', 'New Beverly Cinema')]
# 56

# %%
# write your queries

queryString = """
SELECT DISTINCT ?object ?name
WHERE {
    #BIND SOMETHING
    wd:Q103360 ?p ?object.
    # get the label
    # ?object sc:name ?name
    
    
}

LIMIT 100
"""

print("Result")
x=run_query(queryString)
# Out:
# Result
# [('object', 'http://www.wikidata.org/entity/Q96474679'), ('name', 'award for best direction')]
# [('object', 'http://www.wikidata.org/entity/Q160726'), ('name', 'Ang Lee')]
# [('object', 'http://www.wikidata.org/entity/Q55215'), ('name', 'Alejandro González Iñárritu')]
# [('object', 'http://www.wikidata.org/entity/Q19020'), ('name', 'Academy Awards')]
# [('object', 'http://www.wikidata.org/entity/Q30'), ('name', 'United States of America')]
# [('object', 'http://www.wikidata.org/entity/Q28028'), ('name', 'Alfonso Cuarón')]
# [('object', 'http://www.wikidata.org/entity/Q212329'), ('name', 'Academy of Motion Picture Arts and Sciences')]
# [('object', 'http://www.wikidata.org/entity/Q7146100'), ('name', 'Category:Best Directing Academy Award winners')]
# [('object', 'http://www.wikidata.org/entity/Q6667698'), ('name', 'Template:Academy Award for Best Director')]
# [('object', 'http://www.wikidata.org/entity/Q495980'), ('name', 'Bong Joon-ho')]
# 10

# %% [markdown]
# Final query for this task

# %%
# write your final query

# write your queries

queryString = """
SELECT DISTINCT ?object ?name
WHERE {
    #BIND SOMETHING
    wd:Q103360 ?p ?object.
    # get the label
    # ?object sc:name ?name
    filter REGEX (?name, "Academy Awards")
    
    
}

LIMIT 100
"""

print("Result")
x=run_query(queryString)
# Out:
# Result
# [('object', 'http://www.wikidata.org/entity/Q19020'), ('name', 'Academy Awards')]
# 1

# %% [markdown]
# ## Task 7
# Consider films directed by Woody Allen or Quentin Tarantino separately. Return the film which won more Academy Awards for the two directors (the result set must be two elements - one related to Allen and the other related to Tarantino -  and for each element there must be present the director IRI with its label, the film IRI with its label and the number of Academy awards won).

# %%
# write your queries

# write your final query
# write your queries

# Director Number P57
# FILM Q11424
# WOODEY ALLEN Q25089
# SEARCH ALL THE FLIMS WHOSE IS DIRECTED BY WOODEY ALLEN
# LETS FIND PUBLICATON YEAR
# FIND PUBLICATION YEAR OF EACH FILIM

# tRY TO FIND WITH FIRST DATE OF PUBLICATion

queryString = """
SELECT DISTINCT ?director ?dirName ?film ?filmName ?academnyAward ?academyAwardName
WHERE {
   # bind something
   # ?academnyAward wdt:P31 wd:Q19020.
   # ?film wdt:P31 wd:Q11424;
   wdt:P57 ?director;
   wdt:P166 ?academnyAward.
   
   # ?director sc:name ?dirName.
   # ?film sc:name ?filmName.
   # ?academnyAward sc:name ?academyAwardName.
   FILTER (?director=wd:Q25089 || ?director=wd:Q3772)
    
}
LIMIT 50
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('director', 'http://www.wikidata.org/entity/Q3772'), ('dirName', 'Quentin Tarantino'), ('film', 'http://www.wikidata.org/entity/Q153723'), ('filmName', 'Inglourious Basterds'), ('academnyAward', 'http://www.wikidata.org/entity/Q106291'), ('academyAwardName', 'Academy Award for Best Supporting Actor')]
# [('director', 'http://www.wikidata.org/entity/Q3772'), ('dirName', 'Quentin Tarantino'), ('film', 'http://www.wikidata.org/entity/Q47300912'), ('filmName', 'Once Upon a Time in Hollywood'), ('academnyAward', 'http://www.wikidata.org/entity/Q106291'), ('academyAwardName', 'Academy Award for Best Supporting Actor')]
# [('director', 'http://www.wikidata.org/entity/Q3772'), ('dirName', 'Quentin Tarantino'), ('film', 'http://www.wikidata.org/entity/Q104123'), ('filmName', 'Pulp Fiction'), ('academnyAward', 'http://www.wikidata.org/entity/Q41417'), ('academyAwardName', 'Academy Award for Best Writing, Original Screenplay')]
# [('director', 'http://www.wikidata.org/entity/Q3772'), ('dirName', 'Quentin Tarantino'), ('film', 'http://www.wikidata.org/entity/Q571032'), ('filmName', 'Django Unchained'), ('academnyAward', 'http://www.wikidata.org/entity/Q106291'), ('academyAwardName', 'Academy Award for Best Supporting Actor')]
# [('director', 'http://www.wikidata.org/entity/Q3772'), ('dirName', 'Quentin Tarantino'), ('film', 'http://www.wikidata.org/entity/Q18225084'), ('filmName', 'The Hateful Eight'), ('academnyAward', 'http://www.wikidata.org/entity/Q488651'), ('academyAwardName', 'Academy Award for Best Original Score')]
# [('director', 'http://www.wikidata.org/entity/Q3772'), ('dirName', 'Quentin Tarantino'), ('film', 'http://www.wikidata.org/entity/Q571032'), ('filmName', 'Django Unchained'), ('academnyAward', 'http://www.wikidata.org/entity/Q41417'), ('academyAwardName', 'Academy Award for Best Writing, Original Screenplay')]
# [('director', 'http://www.wikidata.org/entity/Q3772'), ('dirName', 'Quentin Tarantino'), ('film', 'http://www.wikidata.org/entity/Q47300912'), ('filmName', 'Once Upon a Time in Hollywood'), ('academnyAward', 'http://www.wikidata.org/entity/Q277751'), ('academyAwardName', 'Academy Award for Best Production Design')]
# [('director', 'http://www.wikidata.org/entity/Q25089'), ('dirName', 'Woody Allen'), ('film', 'http://www.wikidata.org/entity/Q233464'), ('filmName', 'Annie Hall'), ('academnyAward', 'http://www.wikidata.org/entity/Q103360'), ('academyAwardName', 'Academy Award for Best Director')]
# [('director', 'http://www.wikidata.org/entity/Q25089'), ('dirName', 'Woody Allen'), ('film', 'http://www.wikidata.org/entity/Q1354109'), ('filmName', 'Mighty Aphrodite'), ('academnyAward', 'http://www.wikidata.org/entity/Q106301'), ('academyAwardName', 'Academy Award for Best Supporting Actress')]
# [('director', 'http://www.wikidata.org/entity/Q25089'), ('dirName', 'Woody Allen'), ('film', 'http://www.wikidata.org/entity/Q845057'), ('filmName', 'Hannah and Her Sisters'), ('academnyAward', 'http://www.wikidata.org/entity/Q106291'), ('academyAwardName', 'Academy Award for Best Supporting Actor')]
# [('director', 'http://www.wikidata.org/entity/Q25089'), ('dirName', 'Woody Allen'), ('film', 'http://www.wikidata.org/entity/Q206124'), ('filmName', 'Midnight in Paris'), ('academnyAward', 'http://www.wikidata.org/entity/Q41417'), ('academyAwardName', 'Academy Award for Best Writing, Original Screenplay')]
# [('director', 'http://www.wikidata.org/entity/Q25089'), ('dirName', 'Woody Allen'), ('film', 'http://www.wikidata.org/entity/Q233464'), ('filmName', 'Annie Hall'), ('academnyAward', 'http://www.wikidata.org/entity/Q103618'), ('academyAwardName', 'Academy Award for Best Actress')]
# [('director', 'http://www.wikidata.org/entity/Q25089'), ('dirName', 'Woody Allen'), ('film', 'http://www.wikidata.org/entity/Q212123'), ('filmName', 'Vicky Cristina Barcelona'), ('academnyAward', 'http://www.wikidata.org/entity/Q106301'), ('academyAwardName', 'Academy Award for Best Supporting Actress')]
# [('director', 'http://www.wikidata.org/entity/Q25089'), ('dirName', 'Woody Allen'), ('film', 'http://www.wikidata.org/entity/Q845057'), ('filmName', 'Hannah and Her Sisters'), ('academnyAward', 'http://www.wikidata.org/entity/Q106301'), ('academyAwardName', 'Academy Award for Best Supporting Actress')]
# [('director', 'http://www.wikidata.org/entity/Q25089'), ('dirName', 'Woody Allen'), ('film', 'http://www.wikidata.org/entity/Q2907178'), ('filmName', 'Blue Jasmine'), ('academnyAward', 'http://www.wikidata.org/entity/Q103618'), ('academyAwardName', 'Academy Award for Best Actress')]
# [('director', 'http://www.wikidata.org/entity/Q25089'), ('dirName', 'Woody Allen'), ('film', 'http://www.wikidata.org/entity/Q233464'), ('filmName', 'Annie Hall'), ('academnyAward', 'http://www.wikidata.org/entity/Q102427'), ('academyAwardName', 'Academy Award for Best Picture')]
# [('director', 'http://www.wikidata.org/entity/Q25089'), ('dirName', 'Woody Allen'), ('film', 'http://www.wikidata.org/entity/Q1004531'), ('filmName', 'Bullets Over Broadway'), ('academnyAward', 'http://www.wikidata.org/entity/Q106301'), ('academyAwardName', 'Academy Award for Best Supporting Actress')]
# [('director', 'http://www.wikidata.org/entity/Q25089'), ('dirName', 'Woody Allen'), ('film', 'http://www.wikidata.org/entity/Q845057'), ('filmName', 'Hannah and Her Sisters'), ('academnyAward', 'http://www.wikidata.org/entity/Q41417'), ('academyAwardName', 'Academy Award for Best Writing, Original Screenplay')]
# [('director', 'http://www.wikidata.org/entity/Q25089'), ('dirName', 'Woody Allen'), ('film', 'http://www.wikidata.org/entity/Q233464'), ('filmName', 'Annie Hall'), ('academnyAward', 'http://www.wikidata.org/entity/Q41417'), ('academyAwardName', 'Academy Award for Best Writing, Original Screenplay')]
# 19

# %%
# write your queries

# write your final query
# write your queries

# Director Number P57
# FILM Q11424
# WOODEY ALLEN Q25089
# SEARCH ALL THE FLIMS WHOSE IS DIRECTED BY WOODEY ALLEN
# LETS FIND PUBLICATON YEAR
# FIND PUBLICATION YEAR OF EACH FILIM

# tRY TO FIND WITH FIRST DATE OF PUBLICATion

queryString = """
SELECT DISTINCT ?director ?dirName ?film ?filmName ?academnyAward ?academyAwardName
WHERE {
   # bind something
   # ?academnyAward wdt:P31 wd:Q19020.
   # ?film wdt:P31 wd:Q11424;
   wdt:P57 ?director;
   wdt:P166 ?academnyAward.
   
   # ?director sc:name ?dirName.
   # ?film sc:name ?filmName.
   # ?academnyAward sc:name ?academyAwardName.
   FILTER (?director=wd:Q25089 || ?director=wd:Q3772)
    
}

GROUP BY ?film ?filmName ?director ?directorName
LIMIT 50
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('director', 'http://www.wikidata.org/entity/Q3772'), ('dirName', 'Quentin Tarantino'), ('film', 'http://www.wikidata.org/entity/Q571032'), ('filmName', 'Django Unchained'), ('academnyAward', 'http://www.wikidata.org/entity/Q41417'), ('academyAwardName', 'Academy Award for Best Writing, Original Screenplay')]
# [('director', 'http://www.wikidata.org/entity/Q25089'), ('dirName', 'Woody Allen'), ('film', 'http://www.wikidata.org/entity/Q206124'), ('filmName', 'Midnight in Paris'), ('academnyAward', 'http://www.wikidata.org/entity/Q41417'), ('academyAwardName', 'Academy Award for Best Writing, Original Screenplay')]
# [('director', 'http://www.wikidata.org/entity/Q25089'), ('dirName', 'Woody Allen'), ('film', 'http://www.wikidata.org/entity/Q233464'), ('filmName', 'Annie Hall'), ('academnyAward', 'http://www.wikidata.org/entity/Q102427'), ('academyAwardName', 'Academy Award for Best Picture')]
# [('director', 'http://www.wikidata.org/entity/Q25089'), ('dirName', 'Woody Allen'), ('film', 'http://www.wikidata.org/entity/Q233464'), ('filmName', 'Annie Hall'), ('academnyAward', 'http://www.wikidata.org/entity/Q103360'), ('academyAwardName', 'Academy Award for Best Director')]
# [('director', 'http://www.wikidata.org/entity/Q25089'), ('dirName', 'Woody Allen'), ('film', 'http://www.wikidata.org/entity/Q1354109'), ('filmName', 'Mighty Aphrodite'), ('academnyAward', 'http://www.wikidata.org/entity/Q106301'), ('academyAwardName', 'Academy Award for Best Supporting Actress')]
# [('director', 'http://www.wikidata.org/entity/Q25089'), ('dirName', 'Woody Allen'), ('film', 'http://www.wikidata.org/entity/Q233464'), ('filmName', 'Annie Hall'), ('academnyAward', 'http://www.wikidata.org/entity/Q41417'), ('academyAwardName', 'Academy Award for Best Writing, Original Screenplay')]
# [('director', 'http://www.wikidata.org/entity/Q3772'), ('dirName', 'Quentin Tarantino'), ('film', 'http://www.wikidata.org/entity/Q153723'), ('filmName', 'Inglourious Basterds'), ('academnyAward', 'http://www.wikidata.org/entity/Q106291'), ('academyAwardName', 'Academy Award for Best Supporting Actor')]
# [('director', 'http://www.wikidata.org/entity/Q25089'), ('dirName', 'Woody Allen'), ('film', 'http://www.wikidata.org/entity/Q212123'), ('filmName', 'Vicky Cristina Barcelona'), ('academnyAward', 'http://www.wikidata.org/entity/Q106301'), ('academyAwardName', 'Academy Award for Best Supporting Actress')]
# [('director', 'http://www.wikidata.org/entity/Q25089'), ('dirName', 'Woody Allen'), ('film', 'http://www.wikidata.org/entity/Q1004531'), ('filmName', 'Bullets Over Broadway'), ('academnyAward', 'http://www.wikidata.org/entity/Q106301'), ('academyAwardName', 'Academy Award for Best Supporting Actress')]
# [('director', 'http://www.wikidata.org/entity/Q3772'), ('dirName', 'Quentin Tarantino'), ('film', 'http://www.wikidata.org/entity/Q47300912'), ('filmName', 'Once Upon a Time in Hollywood'), ('academnyAward', 'http://www.wikidata.org/entity/Q277751'), ('academyAwardName', 'Academy Award for Best Production Design')]
# [('director', 'http://www.wikidata.org/entity/Q3772'), ('dirName', 'Quentin Tarantino'), ('film', 'http://www.wikidata.org/entity/Q571032'), ('filmName', 'Django Unchained'), ('academnyAward', 'http://www.wikidata.org/entity/Q106291'), ('academyAwardName', 'Academy Award for Best Supporting Actor')]
# [('director', 'http://www.wikidata.org/entity/Q25089'), ('dirName', 'Woody Allen'), ('film', 'http://www.wikidata.org/entity/Q233464'), ('filmName', 'Annie Hall'), ('academnyAward', 'http://www.wikidata.org/entity/Q103618'), ('academyAwardName', 'Academy Award for Best Actress')]
# [('director', 'http://www.wikidata.org/entity/Q25089'), ('dirName', 'Woody Allen'), ('film', 'http://www.wikidata.org/entity/Q845057'), ('filmName', 'Hannah and Her Sisters'), ('academnyAward', 'http://www.wikidata.org/entity/Q106301'), ('academyAwardName', 'Academy Award for Best Supporting Actress')]
# [('director', 'http://www.wikidata.org/entity/Q25089'), ('dirName', 'Woody Allen'), ('film', 'http://www.wikidata.org/entity/Q845057'), ('filmName', 'Hannah and Her Sisters'), ('academnyAward', 'http://www.wikidata.org/entity/Q106291'), ('academyAwardName', 'Academy Award for Best Supporting Actor')]
# [('director', 'http://www.wikidata.org/entity/Q3772'), ('dirName', 'Quentin Tarantino'), ('film', 'http://www.wikidata.org/entity/Q47300912'), ('filmName', 'Once Upon a Time in Hollywood'), ('academnyAward', 'http://www.wikidata.org/entity/Q106291'), ('academyAwardName', 'Academy Award for Best Supporting Actor')]
# [('director', 'http://www.wikidata.org/entity/Q3772'), ('dirName', 'Quentin Tarantino'), ('film', 'http://www.wikidata.org/entity/Q104123'), ('filmName', 'Pulp Fiction'), ('academnyAward', 'http://www.wikidata.org/entity/Q41417'), ('academyAwardName', 'Academy Award for Best Writing, Original Screenplay')]
# [('director', 'http://www.wikidata.org/entity/Q3772'), ('dirName', 'Quentin Tarantino'), ('film', 'http://www.wikidata.org/entity/Q18225084'), ('filmName', 'The Hateful Eight'), ('academnyAward', 'http://www.wikidata.org/entity/Q488651'), ('academyAwardName', 'Academy Award for Best Original Score')]
# [('director', 'http://www.wikidata.org/entity/Q25089'), ('dirName', 'Woody Allen'), ('film', 'http://www.wikidata.org/entity/Q2907178'), ('filmName', 'Blue Jasmine'), ('academnyAward', 'http://www.wikidata.org/entity/Q103618'), ('academyAwardName', 'Academy Award for Best Actress')]
# [('director', 'http://www.wikidata.org/entity/Q25089'), ('dirName', 'Woody Allen'), ('film', 'http://www.wikidata.org/entity/Q845057'), ('filmName', 'Hannah and Her Sisters'), ('academnyAward', 'http://www.wikidata.org/entity/Q41417'), ('academyAwardName', 'Academy Award for Best Writing, Original Screenplay')]
# 19

# %%
# write your queries

# write your final query
# write your queries




queryString = """
SELECT DISTINCT ?director ?dirName (MAX(?numAwards) AS ?maxAwards)
WHERE {
SELECT DISTINCT ?director ?dirName ?film ?filmName (COUNT(?academnyAward) AS ?numAwards)
WHERE {
   # bind something
   # ?academnyAward wdt:P31 wd:Q19020.
   # ?film wdt:P31 wd:Q11424;
   wdt:P57 ?director;
   wdt:P166 ?academnyAward.
   
   # ?director sc:name ?dirName.
   # ?film sc:name ?filmName.
   # ?academnyAward sc:name ?academyAwardName.
   FILTER(?director=wd:Q25089 || ?director=wd:Q3772)
    
}
GROUP BY ?film ?filmName ?director ?directorName
}
GROUP BY ?director ?directorName
LIMIT 50
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# The operation failed QueryBadFormed: a bad request has been sent to the endpoint, probably the sparql query is bad formed.
#
# Response:
# b'Virtuoso 37000 Error SP031: SPARQL compiler: Variable ?dirName is used in the result set outside aggregate and not mentioned in GROUP BY clause\n\nSPARQL query:\ndefine sql:big-data-const 0\n#output-format:application/sparql-results+json\n\n##-4ddda0dbce-##\nPREFIX wd: <http://www.wikidata.org/entity/> \nPREFIX wdt: <http://www.wikidata.org/prop/direct/> \nPREFIX sc: <http://schema.org/>\n\n\nSELECT DISTINCT ?director ?dirName (MAX(?numAwards) AS ?maxAwards)\nWHERE {\nSELECT DISTINCT ?director ?dirName ?film ?filmName (COUNT(?academnyAward) AS ?numAwards)\nWHERE {\n   # bind something\n   ?academnyAward wdt:P31 wd:Q19020.\n   ?film wdt:P31 wd:Q11424;\n   wdt:P57 ?director;\n   wdt:P166 ?academnyAward.\n   \n   ?director sc:name ?dirName.\n   ?film sc:name ?filmName.\n   ?academnyAward sc:name ?academyAwardName.\n   FILTER(?director=wd:Q25089 || ?director=wd:Q3772)\n    \n}\nGROUP BY ?film ?filmName ?director ?directorName\n}\nGROUP BY ?director ?directorName\nLIMIT 50\n'

# %% [markdown]
# Final query for this task

# %%
# write your final query

# %% [markdown]
# ## Task 8
# Consider the set of films directed by Allen or Tarantino. Return for each Academy Award the total number of nomination of these films (the result set must be a list of triples Academy Award IRI, label and #nomination).

# %%
# write your queries

# %% [markdown]
# Final query for this task

# %%
# write your final query

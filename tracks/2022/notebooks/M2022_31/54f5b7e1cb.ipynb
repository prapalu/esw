# %% [markdown]
# # General instructions
#
# The goal of the project is to materialize a set of **exploratory workloads** over a real-world, large-scale,  open-domain KG: [WikiData](https://www.wikidata.org/wiki/Wikidata:Main_Page)
#
# An exploratory workload  is composed by a set of queries, where each query is related to the information obtained previously.
#
# An exploratory workload starts with a usually vague, open ended question, and does not assume the person issuing the workload has a clear understanding of the data contained in the target database or its structure.
#
# Remeber that:
#
# 1. All the queries must run in the python notebook
# 2. You can use classes and properties only if you find them via a SPARQL query that must be present in the notebook
# 3. You do not delete useless queries. Keep everything that is synthatically valid
#
# ```
# ?p <http://schema.org/name> ?name .
# ```
#
#     is the BGP returning a human-readable name of a property or a class in Wikidata.

# %%
## SETUP used later

from SPARQLWrapper import SPARQLWrapper, JSON


prefixString = """
##-54f5b7e1cb-##
PREFIX wd: <http://www.wikidata.org/entity/> 
PREFIX wdt: <http://www.wikidata.org/prop/direct/> 
PREFIX sc: <http://schema.org/>
"""

# select and construct queries
def run_query(queryString,verbose = True):
    to_run = prefixString + "\n" + queryString

    sparql = SPARQLWrapper("http://a256-gc1-03.srv.aau.dk:5820/sparql")
    sparql.setTimeout(300)
    sparql.setReturnFormat(JSON)
    sparql.setQuery(to_run)

    try :
        results = sparql.query()
        json_results = results.convert()
        if len(json_results['results']['bindings'])==0:
            print("Empty")
            return []
        array = []
        for bindings in json_results['results']['bindings']:
            app =  [ (var, value['value'])  for var, value in bindings.items() ] 
            if verbose:
                print( app)
            array.append(app)
        if verbose:
            print(len(array))
        return array

    except Exception as e :
        print("The operation failed", e)
    
# ASk queries
def run_ask_query(queryString):
    to_run = prefixString + "\n" + queryString

    sparql = SPARQLWrapper("http://a256-gc1-03.srv.aau.dk:5820/sparql")
    sparql.setTimeout(300)
    sparql.setReturnFormat(JSON)
    sparql.setQuery(to_run)

    try :
        return sparql.query().convert()

    except Exception as e :
        print("The operation failed", e)

# %% [markdown]
# # Movie Workflow Series ("Production company explorative search")
#
# Consider the following exploratory information need:
#
# > investigate the main companies working on cinema-related content. We want to know which are the main television production companies and the film production companies, which company distributes more film and some consideration about awards.

# %% [markdown]
# ## Useful URIs for the current workflow
# The following are given:
#
# | IRI           | Description   | Role      |
# | -----------   | -----------   |-----------|
# | `wdt:P1647`   | subproperty   | predicate |
# | `wdt:P31`     | instance of   | predicate |
# | `wdt:P106`    | profession    | predicate |
# | `wdt:P279`    | subclass      | predicate |
# | `wdt:P27`     | nationality   | predicate |
# | `wdt:P106`     | profession   | predicate |
# | `wd:Q5`| Human       | node |
# | `wd:Q36479`    | The Lion King      | node |

# %% [markdown]
# Also consider
#
# ```
# wd:Q36479 ?p ?obj .
# ```
#
# is the BGP to retrieve all **properties of The Lion King**
#
# Please consider that when you return a resource, you should return the IRI and the label of the resource. In particular, when the task require you to identify a BGP the result set must always be a list of couples IRI - label.
#
# The workload should:
#
#
# 1. Identify the BGP for films
#
# 2. Identify the BGP for Netflix
#
# 3. Identify the BGP for television production company
#
# 4. Identify the BGP for film production company
#
# 5. Find the top-5 companies (amongst television production company and film production company) which produced the highest number of crime films (the result set must be a list of triples company IRI, label and #crime film).
#
# 6. Find the company (amongst television production company and film production company) which distributed more films (of any kind of film genre) that they did not produce (the result set must be a list of triples company IRI, label and #film).
#
# 7. Find how many company are listed in every stock exchange market (the result set must be a list of triples stock exchange IRI, label and #companies).
#
# 8. Identify the BGP for Academy Award
#
# 9. Find the companies (among television and film production companies) that won at least 5 Academy Awards for Best Actress for the movies they produced (the result set must be a list of triples company IRI, label and #awards).

# %% [markdown]
# ## Task 1
# Identify the BGP for films

# %%
# query example
queryString = """
SELECT DISTINCT ?p ?name
WHERE {
   # bind something
   wd:Q36479 ?p ?obj .
   # get the label
   # ?p sc:name ?name.
}
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P3092'), ('name', 'film crew member')]
# [('p', 'http://www.wikidata.org/prop/direct/P4021'), ('name', 'danskefilm animated film ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7679'), ('name', 'Cinépolis KLIC ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1015'), ('name', 'NORAF ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1040'), ('name', 'film editor')]
# [('p', 'http://www.wikidata.org/prop/direct/P1237'), ('name', 'Box Office Mojo film ID (former scheme)')]
# [('p', 'http://www.wikidata.org/prop/direct/P1258'), ('name', 'Rotten Tomatoes ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1265'), ('name', 'AlloCiné film ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1273'), ('name', 'CANTIC ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P136'), ('name', 'genre')]
# [('p', 'http://www.wikidata.org/prop/direct/P1411'), ('name', 'nominated for')]
# [('p', 'http://www.wikidata.org/prop/direct/P1417'), ('name', 'Encyclopædia Britannica Online ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1434'), ('name', 'takes place in fictional universe')]
# [('p', 'http://www.wikidata.org/prop/direct/P144'), ('name', 'based on')]
# [('p', 'http://www.wikidata.org/prop/direct/P1476'), ('name', 'title')]
# [('p', 'http://www.wikidata.org/prop/direct/P154'), ('name', 'logo image')]
# [('p', 'http://www.wikidata.org/prop/direct/P1552'), ('name', 'has quality')]
# [('p', 'http://www.wikidata.org/prop/direct/P156'), ('name', 'followed by')]
# [('p', 'http://www.wikidata.org/prop/direct/P1562'), ('name', 'AllMovie title ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P162'), ('name', 'producer')]
# 20

# %%
# Lion King all props
queryString = """
SELECT DISTINCT ?p ?name
WHERE {
   # bind something
   wd:Q36479 ?p ?obj .
   # get the label
   # ?p sc:name ?name.
}
ORDER BY ASC(?name)
LIMIT 1000
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P3593'), ('name', 'AFI Catalog of Feature Films ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7118'), ('name', 'AMPAS collections film ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6145'), ('name', 'Academy Awards Database film ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1562'), ('name', 'AllMovie title ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2465'), ('name', 'Allcinema film ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1265'), ('name', 'AlloCiné film ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P9586'), ('name', 'Apple TV movie ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3280'), ('name', 'BAnQ author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P4632'), ('name', 'Bechdel Test Movie List ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5384'), ('name', 'Behind The Voice Actors film ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P950'), ('name', 'Biblioteca Nacional de España ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P268'), ('name', 'Bibliothèque nationale de France ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P4933'), ('name', 'Big Cartoon Database ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1237'), ('name', 'Box Office Mojo film ID (former scheme)')]
# [('p', 'http://www.wikidata.org/prop/direct/P1273'), ('name', 'CANTIC ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2758'), ('name', 'CNC film rating (France)')]
# [('p', 'http://www.wikidata.org/prop/direct/P3402'), ('name', 'CNC film rating (Romania)')]
# [('p', 'http://www.wikidata.org/prop/direct/P4665'), ('name', 'CineMagia title ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3077'), ('name', 'Cineplex Germany film ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3203'), ('name', 'Ciné-Ressources film ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P4276'), ('name', 'Cinémathèque québécoise work identifier')]
# [('p', 'http://www.wikidata.org/prop/direct/P7679'), ('name', 'Cinépolis KLIC ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5905'), ('name', 'Comic Vine ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P373'), ('name', 'Commons category')]
# [('p', 'http://www.wikidata.org/prop/direct/P1804'), ('name', 'DNF film ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3509'), ('name', 'Dagens Nyheter topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3844'), ('name', 'Deutsche Synchronkartei film ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6181'), ('name', 'Disney A to Z ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7595'), ('name', 'Disney+ movie ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P4529'), ('name', 'Douban film ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2704'), ('name', 'EIDR content ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2346'), ('name', 'Elonet movie ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1417'), ('name', 'Encyclopædia Britannica Online ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6262'), ('name', 'Fandom article ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P480'), ('name', 'FilmAffinity ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7975'), ('name', 'Filmfront film ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2747'), ('name', 'Filmiroda rating')]
# [('p', 'http://www.wikidata.org/prop/direct/P646'), ('name', 'Freebase ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7818'), ('name', 'French Vikidia ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P227'), ('name', 'GND ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6562'), ('name', 'Google Play Movies & TV ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P345'), ('name', 'IMDb ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P4483'), ('name', 'INDUCKS story ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3212'), ('name', 'ISAN')]
# [('p', 'http://www.wikidata.org/prop/direct/P3110'), ('name', 'ISzDb film ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5099'), ('name', 'Il mondo dei doppiatori ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2508'), ('name', 'KINENOTE film ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5311'), ('name', 'Kino-teatr.ua film ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2603'), ('name', 'Kinopoisk film ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8847'), ('name', 'Kinorium movie ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P4282'), ('name', 'LUMIERE film ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3107'), ('name', 'LdiF ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6127'), ('name', 'Letterboxd film ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P244'), ('name', 'Library of Congress authority ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7212'), ('name', 'LyricsTranslate ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1657'), ('name', 'MPAA film rating')]
# [('p', 'http://www.wikidata.org/prop/direct/P7299'), ('name', 'MUBI film ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1712'), ('name', 'Metacritic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5885'), ('name', 'Microsoft Store product ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8033'), ('name', 'Movie Review Query Engine ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1970'), ('name', 'MovieMeter film ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5786'), ('name', 'Moviepilot.de film ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1015'), ('name', 'NORAF ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P4619'), ('name', 'National Library of Brazil ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1874'), ('name', 'Netflix ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6900'), ('name', 'NicoNicoPedia ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3138'), ('name', 'OFDb film ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3302'), ('name', 'Open Media Database film ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7293'), ('name', 'PLWABN ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P905'), ('name', 'PORT film ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P4515'), ('name', 'Prisma ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3417'), ('name', 'Quora topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3834'), ('name', 'RTC film rating')]
# [('p', 'http://www.wikidata.org/prop/direct/P1258'), ('name', 'Rotten Tomatoes ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2518'), ('name', 'Scope.dk film ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3854'), ('name', 'Soundtrack Collector ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2334'), ('name', 'Swedish Film Database film ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2631'), ('name', 'TCM Movie Database film ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P4947'), ('name', 'TMDb movie ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3804'), ('name', 'TV Guide show ID (former scheme)')]
# [('p', 'http://www.wikidata.org/prop/direct/P6839'), ('name', 'TV Tropes identifier')]
# [('p', 'http://www.wikidata.org/prop/direct/P2638'), ('name', 'TV.com ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3808'), ('name', 'The Numbers movie ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P214'), ('name', 'VIAF ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3553'), ('name', 'Zhihu topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6942'), ('name', 'animator')]
# [('p', 'http://www.wikidata.org/prop/direct/P3174'), ('name', 'art director')]
# [('p', 'http://www.wikidata.org/prop/direct/P5021'), ('name', 'assessment')]
# [('p', 'http://www.wikidata.org/prop/direct/P166'), ('name', 'award received')]
# [('p', 'http://www.wikidata.org/prop/direct/P144'), ('name', 'based on')]
# [('p', 'http://www.wikidata.org/prop/direct/P2142'), ('name', 'box office')]
# [('p', 'http://www.wikidata.org/prop/direct/P2769'), ('name', 'budget')]
# [('p', 'http://www.wikidata.org/prop/direct/P674'), ('name', 'characters')]
# [('p', 'http://www.wikidata.org/prop/direct/P4786'), ('name', 'cinematografo film ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P462'), ('name', 'color')]
# [('p', 'http://www.wikidata.org/prop/direct/P86'), ('name', 'composer')]
# [('p', 'http://www.wikidata.org/prop/direct/P2130'), ('name', 'cost')]
# [('p', 'http://www.wikidata.org/prop/direct/P495'), ('name', 'country of origin')]
# [('p', 'http://www.wikidata.org/prop/direct/P4021'), ('name', 'danskefilm animated film ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P4969'), ('name', 'derivative work')]
# [('p', 'http://www.wikidata.org/prop/direct/P1889'), ('name', 'different from')]
# [('p', 'http://www.wikidata.org/prop/direct/P57'), ('name', 'director')]
# [('p', 'http://www.wikidata.org/prop/direct/P750'), ('name', 'distributed by')]
# [('p', 'http://www.wikidata.org/prop/direct/P437'), ('name', 'distribution format')]
# [('p', 'http://www.wikidata.org/prop/direct/P2047'), ('name', 'duration')]
# [('p', 'http://www.wikidata.org/prop/direct/P1431'), ('name', 'executive producer')]
# [('p', 'http://www.wikidata.org/prop/direct/P2755'), ('name', 'exploitation visa number')]
# [('p', 'http://www.wikidata.org/prop/direct/P2079'), ('name', 'fabrication method')]
# [('p', 'http://www.wikidata.org/prop/direct/P3092'), ('name', 'film crew member')]
# [('p', 'http://www.wikidata.org/prop/direct/P1040'), ('name', 'film editor')]
# [('p', 'http://www.wikidata.org/prop/direct/P156'), ('name', 'followed by')]
# [('p', 'http://www.wikidata.org/prop/direct/P136'), ('name', 'genre')]
# [('p', 'http://www.wikidata.org/prop/direct/P747'), ('name', 'has edition or translation')]
# [('p', 'http://www.wikidata.org/prop/direct/P1552'), ('name', 'has quality')]
# [('p', 'http://www.wikidata.org/prop/direct/P6398'), ('name', 'iTunes movie ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P941'), ('name', 'inspired by')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('name', 'instance of')]
# [('p', 'http://www.wikidata.org/prop/direct/P154'), ('name', 'logo image')]
# [('p', 'http://www.wikidata.org/prop/direct/P8345'), ('name', 'media franchise')]
# [('p', 'http://www.wikidata.org/prop/direct/P840'), ('name', 'narrative location')]
# [('p', 'http://www.wikidata.org/prop/direct/P1411'), ('name', 'nominated for')]
# [('p', 'http://www.wikidata.org/prop/direct/P856'), ('name', 'official website')]
# [('p', 'http://www.wikidata.org/prop/direct/P364'), ('name', 'original language of film or TV show')]
# [('p', 'http://www.wikidata.org/prop/direct/P179'), ('name', 'part of the series')]
# [('p', 'http://www.wikidata.org/prop/direct/P175'), ('name', 'performer')]
# [('p', 'http://www.wikidata.org/prop/direct/P162'), ('name', 'producer')]
# [('p', 'http://www.wikidata.org/prop/direct/P2364'), ('name', 'production code')]
# [('p', 'http://www.wikidata.org/prop/direct/P272'), ('name', 'production company')]
# [('p', 'http://www.wikidata.org/prop/direct/P2554'), ('name', 'production designer')]
# [('p', 'http://www.wikidata.org/prop/direct/P577'), ('name', 'publication date')]
# [('p', 'http://www.wikidata.org/prop/direct/P58'), ('name', 'screenwriter')]
# [('p', 'http://www.wikidata.org/prop/direct/P8411'), ('name', 'set in environment')]
# [('p', 'http://www.wikidata.org/prop/direct/P793'), ('name', 'significant event')]
# [('p', 'http://www.wikidata.org/prop/direct/P406'), ('name', 'soundtrack release')]
# [('p', 'http://www.wikidata.org/prop/direct/P3275'), ('name', 'storyboard artist')]
# [('p', 'http://www.wikidata.org/prop/direct/P1434'), ('name', 'takes place in fictional universe')]
# [('p', 'http://www.wikidata.org/prop/direct/P942'), ('name', 'theme music')]
# [('p', 'http://www.wikidata.org/prop/direct/P1476'), ('name', 'title')]
# [('p', 'http://www.wikidata.org/prop/direct/P910'), ('name', "topic's main category")]
# [('p', 'http://www.wikidata.org/prop/direct/P725'), ('name', 'voice actor')]
# [('p', 'http://www.wikidata.org/prop/direct/P2529'), ('name', 'ČSFD film ID')]
# 141

# %%
# Lion King instance of
queryString = """
SELECT DISTINCT ?obj ?oName
WHERE {
   # bind something
   wd:Q36479 wdt:P31 ?obj .
   # get the label
   # ?obj sc:name ?oName.
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('obj', 'http://www.wikidata.org/entity/Q29168811'), ('oName', 'animated feature film')]
# 1

# %%
# animated feature film
queryString = """
SELECT DISTINCT ?p ?name ?obj ?oName
WHERE {
   # bind something
   wd:Q29168811 ?p ?obj .
   # get the label
   # ?p sc:name ?name.
   # ?obj sc:name ?oName.
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P461'), ('name', 'opposite of'), ('obj', 'http://www.wikidata.org/entity/Q17517379'), ('oName', 'animated short film')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('name', 'subclass of'), ('obj', 'http://www.wikidata.org/entity/Q202866'), ('oName', 'animated film')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('name', 'subclass of'), ('obj', 'http://www.wikidata.org/entity/Q24869'), ('oName', 'feature film')]
# [('p', 'http://www.wikidata.org/prop/direct/P910'), ('name', "topic's main category"), ('obj', 'http://www.wikidata.org/entity/Q8254220'), ('oName', 'Category:Animated feature films')]
# 4

# %%
# animated film
queryString = """
SELECT DISTINCT ?p ?name ?obj ?oName
WHERE {
   # bind something
   wd:Q202866 ?p ?obj .
   # get the label
   # ?p sc:name ?name.
   # ?obj sc:name ?oName.
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('name', 'properties for this type'), ('obj', 'http://www.wikidata.org/entity/P345'), ('oName', 'IMDb ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5869'), ('name', 'model item'), ('obj', 'http://www.wikidata.org/entity/Q134430'), ('oName', 'Snow White and the Seven Dwarfs')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('name', 'properties for this type'), ('obj', 'http://www.wikidata.org/entity/P2047'), ('oName', 'duration')]
# [('p', 'http://www.wikidata.org/prop/direct/P910'), ('name', "topic's main category"), ('obj', 'http://www.wikidata.org/entity/Q6522809'), ('oName', 'Category:Animated films')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('name', 'properties for this type'), ('obj', 'http://www.wikidata.org/entity/P2079'), ('oName', 'fabrication method')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('name', 'properties for this type'), ('obj', 'http://www.wikidata.org/entity/P921'), ('oName', 'main subject')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('name', 'subclass of'), ('obj', 'http://www.wikidata.org/entity/Q11424'), ('oName', 'film')]
# [('p', 'http://www.wikidata.org/prop/direct/P2079'), ('name', 'fabrication method'), ('obj', 'http://www.wikidata.org/entity/Q11425'), ('oName', 'animation')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('name', 'properties for this type'), ('obj', 'http://www.wikidata.org/entity/P577'), ('oName', 'publication date')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('name', 'properties for this type'), ('obj', 'http://www.wikidata.org/entity/P495'), ('oName', 'country of origin')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('name', 'properties for this type'), ('obj', 'http://www.wikidata.org/entity/P136'), ('oName', 'genre')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('name', 'properties for this type'), ('obj', 'http://www.wikidata.org/entity/P840'), ('oName', 'narrative location')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('name', 'properties for this type'), ('obj', 'http://www.wikidata.org/entity/P86'), ('oName', 'composer')]
# [('p', 'http://www.wikidata.org/prop/direct/P461'), ('name', 'opposite of'), ('obj', 'http://www.wikidata.org/entity/Q517386'), ('oName', 'live action')]
# [('p', 'http://www.wikidata.org/prop/direct/P5869'), ('name', 'model item'), ('obj', 'http://www.wikidata.org/entity/Q15270647'), ('oName', 'Zootopia')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('name', 'properties for this type'), ('obj', 'http://www.wikidata.org/entity/P2554'), ('oName', 'production designer')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('name', 'properties for this type'), ('obj', 'http://www.wikidata.org/entity/P57'), ('oName', 'director')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('name', 'properties for this type'), ('obj', 'http://www.wikidata.org/entity/P58'), ('oName', 'screenwriter')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('name', 'properties for this type'), ('obj', 'http://www.wikidata.org/entity/P144'), ('oName', 'based on')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('name', 'properties for this type'), ('obj', 'http://www.wikidata.org/entity/P3275'), ('oName', 'storyboard artist')]
# [('p', 'http://www.wikidata.org/prop/direct/P1424'), ('name', "topic's main template"), ('obj', 'http://www.wikidata.org/entity/Q13583287'), ('oName', 'Template:Infobox animanga/Anime')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('name', 'properties for this type'), ('obj', 'http://www.wikidata.org/entity/P10'), ('oName', 'video')]
# [('p', 'http://www.wikidata.org/prop/direct/P1424'), ('name', "topic's main template"), ('obj', 'http://www.wikidata.org/entity/Q13411747'), ('oName', 'Template:Infobox animanga/Video')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('name', 'properties for this type'), ('obj', 'http://www.wikidata.org/entity/P2603'), ('oName', 'Kinopoisk film ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('name', 'properties for this type'), ('obj', 'http://www.wikidata.org/entity/P1934'), ('oName', 'Animator.ru film ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('name', 'properties for this type'), ('obj', 'http://www.wikidata.org/entity/P725'), ('oName', 'voice actor')]
# [('p', 'http://www.wikidata.org/prop/direct/P4969'), ('name', 'derivative work'), ('obj', 'http://www.wikidata.org/entity/Q18663726'), ('oName', 'Stone Protectors')]
# [('p', 'http://www.wikidata.org/prop/direct/P1424'), ('name', "topic's main template"), ('obj', 'http://www.wikidata.org/entity/Q13091155'), ('oName', 'Template:Infobox cartoon film')]
# [('p', 'http://www.wikidata.org/prop/direct/P1424'), ('name', "topic's main template"), ('obj', 'http://www.wikidata.org/entity/Q18991727'), ('oName', 'Template:Infobox animanga/Movie')]
# 29

# %%
# feature film
queryString = """
SELECT DISTINCT ?p ?name ?obj ?oName
WHERE {
   # bind something
   wd:Q24869 ?p ?obj .
   # get the label
   # ?p sc:name ?name.
   # ?obj sc:name ?oName.
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('name', 'subclass of'), ('obj', 'http://www.wikidata.org/entity/Q11424'), ('oName', 'film')]
# [('p', 'http://www.wikidata.org/prop/direct/P1552'), ('name', 'has quality'), ('obj', 'http://www.wikidata.org/entity/Q2199864'), ('oName', 'duration')]
# [('p', 'http://www.wikidata.org/prop/direct/P461'), ('name', 'opposite of'), ('obj', 'http://www.wikidata.org/entity/Q24862'), ('oName', 'short film')]
# [('p', 'http://www.wikidata.org/prop/direct/P5135'), ('name', 'greater than'), ('obj', 'http://www.wikidata.org/entity/Q24862'), ('oName', 'short film')]
# [('p', 'http://www.wikidata.org/prop/direct/P5135'), ('name', 'greater than'), ('obj', 'http://www.wikidata.org/entity/Q24865'), ('oName', 'medium-length film')]
# [('p', 'http://www.wikidata.org/prop/direct/P910'), ('name', "topic's main category"), ('obj', 'http://www.wikidata.org/entity/Q32118748'), ('oName', 'Category:Feature films')]
# 6

# %% [markdown]
# Final query for this task

# %%
# BGP for film
queryString = """
SELECT *
WHERE {
   BIND(wd:Q11424 AS ?iri)
   # ?iri sc:name ?name.
}
LIMIT 10
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('iri', 'http://www.wikidata.org/entity/Q11424'), ('name', 'film')]
# 1

# %% [markdown]
# ## Task 2
# Identify the BGP for Netflix

# %%
#props of netflix id of Lion King
queryString = """
SELECT DISTINCT ?p ?name
WHERE {
   wd:Q36479 wdt:P1874 ?obj . #obj is netflx id
   # ?obj ?p ?o.
   # ?p sc:name ?name.
}
ORDER BY ASC(?name)
LIMIT 1000
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# Empty

# %%
#what distributed Lion King
queryString = """
SELECT DISTINCT ?obj ?name
WHERE {
   wd:Q36479 wdt:P750 ?obj . #distributed by obj
   # ?obj  sc:name ?name.
}
ORDER BY ASC(?name)
LIMIT 1000
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('obj', 'http://www.wikidata.org/entity/Q54958752'), ('name', 'Disney+')]
# [('obj', 'http://www.wikidata.org/entity/Q1097348'), ('name', 'InterCom')]
# [('obj', 'http://www.wikidata.org/entity/Q135288'), ('name', 'Microsoft Store')]
# [('obj', 'http://www.wikidata.org/entity/Q907311'), ('name', 'Netflix')]
# [('obj', 'http://www.wikidata.org/entity/Q1323594'), ('name', 'Walt Disney Studios Motion Pictures')]
# 5

# %% [markdown]
# Final query for this task

# %%
# BGP for Netflix
queryString = """
SELECT *
WHERE {
   BIND(wd:Q907311 AS ?iri)
   # ?iri sc:name ?name.
}
LIMIT 10
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('iri', 'http://www.wikidata.org/entity/Q907311'), ('name', 'Netflix')]
# 1

# %% [markdown]
# ## Task 3
# Identify the BGP for television production company

# %%
# Netflix props
queryString = """
SELECT DISTINCT ?p ?name
WHERE {
   wd:Q907311 ?p ?o.
   # ?p sc:name ?name.
}
LIMIT 1000
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P8939'), ('name', 'Google Play developer slug')]
# [('p', 'http://www.wikidata.org/prop/direct/P1056'), ('name', 'product or material produced')]
# [('p', 'http://www.wikidata.org/prop/direct/P112'), ('name', 'founded by')]
# [('p', 'http://www.wikidata.org/prop/direct/P1128'), ('name', 'employees')]
# [('p', 'http://www.wikidata.org/prop/direct/P127'), ('name', 'owned by')]
# [('p', 'http://www.wikidata.org/prop/direct/P1411'), ('name', 'nominated for')]
# [('p', 'http://www.wikidata.org/prop/direct/P1417'), ('name', 'Encyclopædia Britannica Online ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1424'), ('name', "topic's main template")]
# [('p', 'http://www.wikidata.org/prop/direct/P1454'), ('name', 'legal form')]
# [('p', 'http://www.wikidata.org/prop/direct/P154'), ('name', 'logo image')]
# [('p', 'http://www.wikidata.org/prop/direct/P1581'), ('name', 'official blog')]
# [('p', 'http://www.wikidata.org/prop/direct/P159'), ('name', 'headquarters location')]
# [('p', 'http://www.wikidata.org/prop/direct/P166'), ('name', 'award received')]
# [('p', 'http://www.wikidata.org/prop/direct/P1661'), ('name', 'Alexa rank')]
# [('p', 'http://www.wikidata.org/prop/direct/P1687'), ('name', 'Wikidata property')]
# [('p', 'http://www.wikidata.org/prop/direct/P169'), ('name', 'chief executive officer')]
# [('p', 'http://www.wikidata.org/prop/direct/P17'), ('name', 'country')]
# [('p', 'http://www.wikidata.org/prop/direct/P18'), ('name', 'image')]
# [('p', 'http://www.wikidata.org/prop/direct/P1833'), ('name', 'number of registered users/contributors')]
# [('p', 'http://www.wikidata.org/prop/direct/P1846'), ('name', 'distribution map')]
# [('p', 'http://www.wikidata.org/prop/direct/P2002'), ('name', 'Twitter username')]
# [('p', 'http://www.wikidata.org/prop/direct/P2003'), ('name', 'Instagram username')]
# [('p', 'http://www.wikidata.org/prop/direct/P2013'), ('name', 'Facebook ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2037'), ('name', 'GitHub username')]
# [('p', 'http://www.wikidata.org/prop/direct/P2088'), ('name', 'Crunchbase organization ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2139'), ('name', 'total revenue')]
# [('p', 'http://www.wikidata.org/prop/direct/P214'), ('name', 'VIAF ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P227'), ('name', 'GND ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2283'), ('name', 'uses')]
# [('p', 'http://www.wikidata.org/prop/direct/P2295'), ('name', 'net profit')]
# [('p', 'http://www.wikidata.org/prop/direct/P2397'), ('name', 'YouTube channel ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2403'), ('name', 'total assets')]
# [('p', 'http://www.wikidata.org/prop/direct/P2427'), ('name', 'GRID ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P244'), ('name', 'Library of Congress authority ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2572'), ('name', 'hashtag')]
# [('p', 'http://www.wikidata.org/prop/direct/P268'), ('name', 'Bibliothèque nationale de France ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('name', 'instance of')]
# [('p', 'http://www.wikidata.org/prop/direct/P3106'), ('name', 'Guardian topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3222'), ('name', 'NE.se ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3362'), ('name', 'operating income')]
# [('p', 'http://www.wikidata.org/prop/direct/P3417'), ('name', 'Quora topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3418'), ('name', 'Google Play Store app ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P355'), ('name', 'subsidiary')]
# [('p', 'http://www.wikidata.org/prop/direct/P3553'), ('name', 'Zhihu topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P361'), ('name', 'part of')]
# [('p', 'http://www.wikidata.org/prop/direct/P373'), ('name', 'Commons category')]
# [('p', 'http://www.wikidata.org/prop/direct/P3797'), ('name', 'autonomous system number')]
# [('p', 'http://www.wikidata.org/prop/direct/P3836'), ('name', 'Pinterest username')]
# [('p', 'http://www.wikidata.org/prop/direct/P3861'), ('name', 'App Store app ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3984'), ('name', 'subreddit')]
# [('p', 'http://www.wikidata.org/prop/direct/P400'), ('name', 'platform')]
# [('p', 'http://www.wikidata.org/prop/direct/P4013'), ('name', 'Giphy username')]
# [('p', 'http://www.wikidata.org/prop/direct/P407'), ('name', 'language of work or name')]
# [('p', 'http://www.wikidata.org/prop/direct/P4073'), ('name', 'Fandom wiki ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P414'), ('name', 'stock exchange')]
# [('p', 'http://www.wikidata.org/prop/direct/P4264'), ('name', 'LinkedIn company ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P4342'), ('name', 'Store norske leksikon ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P4354'), ('name', 'search formatter URL')]
# [('p', 'http://www.wikidata.org/prop/direct/P452'), ('name', 'industry')]
# [('p', 'http://www.wikidata.org/prop/direct/P4527'), ('name', 'UK Parliament thesaurus ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P463'), ('name', 'member of')]
# [('p', 'http://www.wikidata.org/prop/direct/P4776'), ('name', 'MAC Address Block Large ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5019'), ('name', 'Brockhaus Enzyklopädie online ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P571'), ('name', 'inception')]
# [('p', 'http://www.wikidata.org/prop/direct/P6181'), ('name', 'Disney A to Z ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6262'), ('name', 'Fandom article ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6366'), ('name', 'Microsoft Academic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P646'), ('name', 'Freebase ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6760'), ('name', 'Know Your Meme ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6782'), ('name', 'ROR ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6839'), ('name', 'TV Tropes identifier')]
# [('p', 'http://www.wikidata.org/prop/direct/P6849'), ('name', 'DR topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6900'), ('name', 'NicoNicoPedia ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P691'), ('name', 'NKCR AUT ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7085'), ('name', 'TikTok username')]
# [('p', 'http://www.wikidata.org/prop/direct/P7157'), ('name', 'The Top Tens ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7306'), ('name', 'Downdetector ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P740'), ('name', 'location of formation')]
# [('p', 'http://www.wikidata.org/prop/direct/P7502'), ('name', 'Golden ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7771'), ('name', 'PersonalData.IO ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7818'), ('name', 'French Vikidia ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7859'), ('name', 'WorldCat Identities ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P856'), ('name', 'official website')]
# [('p', 'http://www.wikidata.org/prop/direct/P8687'), ('name', 'social media followers')]
# [('p', 'http://www.wikidata.org/prop/direct/P910'), ('name', "topic's main category")]
# [('p', 'http://www.wikidata.org/prop/direct/P9100'), ('name', 'GitHub topic')]
# [('p', 'http://www.wikidata.org/prop/direct/P9138'), ('name', 'service status information URL')]
# [('p', 'http://www.wikidata.org/prop/direct/P9346'), ('name', 'France24 topic ID (French)')]
# [('p', 'http://www.wikidata.org/prop/direct/P946'), ('name', 'ISIN')]
# [('p', 'http://www.wikidata.org/prop/direct/P9618'), ('name', 'AlternativeTo software ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P966'), ('name', 'MusicBrainz label ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P973'), ('name', 'described at URL')]
# [('p', 'http://www.wikidata.org/prop/direct/P3242'), ('name', 'SIC code')]
# [('p', 'http://www.wikidata.org/prop/direct/P5531'), ('name', 'Central Index Key')]
# [('p', 'http://www.wikidata.org/prop/direct/P6869'), ('name', 'Hoopla publisher ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7997'), ('name', 'GRY-Online company ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2531'), ('name', 'Box Office Mojo studio ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5576'), ('name', 'EDb company ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6954'), ('name', 'online access status')]
# 99

# %%
# Netflix instance of
queryString = """
SELECT DISTINCT ?o ?name
WHERE {
   wd:Q907311 wdt:P31 ?o.
   # ?o sc:name ?name.
}
LIMIT 1000
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('o', 'http://www.wikidata.org/entity/Q10689397'), ('name', 'television production company')]
# [('o', 'http://www.wikidata.org/entity/Q4830453'), ('name', 'business')]
# [('o', 'http://www.wikidata.org/entity/Q723685'), ('name', 'video on demand')]
# [('o', 'http://www.wikidata.org/entity/Q891723'), ('name', 'public company')]
# [('o', 'http://www.wikidata.org/entity/Q15265344'), ('name', 'broadcaster')]
# [('o', 'http://www.wikidata.org/entity/Q368290'), ('name', 'film distributor')]
# [('o', 'http://www.wikidata.org/entity/Q841645'), ('name', 'Internet television')]
# [('o', 'http://www.wikidata.org/entity/Q1194970'), ('name', 'dot-com company')]
# 8

# %% [markdown]
# Final query for this task

# %%
# BGP for television production company
queryString = """
SELECT *
WHERE {
   BIND(wd:Q10689397 AS ?iri)
   # ?iri sc:name ?name.
}
LIMIT 10
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('iri', 'http://www.wikidata.org/entity/Q10689397'), ('name', 'television production company')]
# 1

# %% [markdown]
# ## Task 4
# Identify the BGP for film production company

# %%
# tv prod company props
queryString = """
SELECT DISTINCT ?p ?name
WHERE {
   wd:Q10689397 ?p ?o.
   # ?p sc:name ?name.
}
LIMIT 1000
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P17'), ('name', 'country')]
# [('p', 'http://www.wikidata.org/prop/direct/P2671'), ('name', 'Google Knowledge Graph ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('name', 'subclass of')]
# [('p', 'http://www.wikidata.org/prop/direct/P3417'), ('name', 'Quora topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P373'), ('name', 'Commons category')]
# [('p', 'http://www.wikidata.org/prop/direct/P452'), ('name', 'industry')]
# [('p', 'http://www.wikidata.org/prop/direct/P910'), ('name', "topic's main category")]
# 7

# %%
# tv prod company subclass of
queryString = """
SELECT DISTINCT ?o ?name
WHERE {
   wd:Q10689397 wdt:P279 ?o.
   # ?o sc:name ?name.
}
LIMIT 1000
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('o', 'http://www.wikidata.org/entity/Q1762059'), ('name', 'film production company')]
# [('o', 'http://www.wikidata.org/entity/Q19364326'), ('name', 'media studio facility')]
# [('o', 'http://www.wikidata.org/entity/Q11396960'), ('name', 'production company')]
# 3

# %% [markdown]
# Final query for this task

# %%
# BGP for film production company
queryString = """
SELECT *
WHERE {
   BIND(wd:Q1762059 AS ?iri)
   # ?iri sc:name ?name.
}
LIMIT 10
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('iri', 'http://www.wikidata.org/entity/Q1762059'), ('name', 'film production company')]
# 1

# %% [markdown]
# ## Task 5
# Find the top-5 companies (amongst television production company and film production company) which produced the highest number of crime films (the result set must be a list of triples company IRI, label and #crime film).

# %%
# Lion King production company
queryString = """
SELECT DISTINCT ?obj ?oName
WHERE {
   # bind something
   wd:Q36479 wdt:P272 ?obj .
   # get the label
   # ?obj sc:name ?oName.
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('obj', 'http://www.wikidata.org/entity/Q191224'), ('oName', 'Walt Disney Pictures')]
# [('obj', 'http://www.wikidata.org/entity/Q1047410'), ('oName', 'Walt Disney Animation Studios')]
# 2

# %%
# Lion King producer
queryString = """
SELECT DISTINCT ?obj ?oName
WHERE {
   # bind something
   wd:Q36479 wdt:P162 ?obj .
   # get the label
   # ?obj sc:name ?oName.
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('obj', 'http://www.wikidata.org/entity/Q1072843'), ('oName', 'Don Hahn')]
# 1

# %%
# instances of film
queryString = """
SELECT DISTINCT ?f ?oName
WHERE {
   # bind something
   # ?f wdt:P31 wd:Q11424.
   # get the label
   # ?f sc:name ?oName.
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('f', 'http://www.wikidata.org/entity/Q8178307'), ('oName', '15 Park Avenue')]
# [('f', 'http://www.wikidata.org/entity/Q8197668'), ('oName', 'Idiot Love')]
# [('f', 'http://www.wikidata.org/entity/Q319263'), ('oName', 'Doctor in the House')]
# [('f', 'http://www.wikidata.org/entity/Q8452990'), ('oName', "Sunday League - Pepik Hnatek's Final Match")]
# [('f', 'http://www.wikidata.org/entity/Q284184'), ('oName', 'Ra.One')]
# [('f', 'http://www.wikidata.org/entity/Q13637926'), ('oName', 'Indra')]
# [('f', 'http://www.wikidata.org/entity/Q13638153'), ('oName', 'Inner Senses')]
# [('f', 'http://www.wikidata.org/entity/Q13645807'), ('oName', 'Madhumasam')]
# [('f', 'http://www.wikidata.org/entity/Q13647258'), ('oName', 'Marupakkam')]
# [('f', 'http://www.wikidata.org/entity/Q13677566'), ('oName', 'Timberjack')]
# [('f', 'http://www.wikidata.org/entity/Q13693967'), ('oName', 'Cross')]
# [('f', 'http://www.wikidata.org/entity/Q15464247'), ('oName', 'What the Fish')]
# [('f', 'http://www.wikidata.org/entity/Q15475237'), ('oName', 'Mediastan')]
# [('f', 'http://www.wikidata.org/entity/Q15490985'), ('oName', 'Jailhouse Heat')]
# [('f', 'http://www.wikidata.org/entity/Q15046558'), ('oName', 'Life After Beth')]
# [('f', 'http://www.wikidata.org/entity/Q15584559'), ('oName', 'Salvation Nell')]
# [('f', 'http://www.wikidata.org/entity/Q15596853'), ('oName', 'Burying the Ex')]
# [('f', 'http://www.wikidata.org/entity/Q10323448'), ('oName', 'Mamata')]
# [('f', 'http://www.wikidata.org/entity/Q12360731'), ('oName', 'The Phantom of the Opera')]
# [('f', 'http://www.wikidata.org/entity/Q13732569'), ('oName', 'Move On')]
# [('f', 'http://www.wikidata.org/entity/Q15721015'), ('oName', 'Mamathe')]
# [('f', 'http://www.wikidata.org/entity/Q15721180'), ('oName', 'Midida Hrudayagalu')]
# [('f', 'http://www.wikidata.org/entity/Q15721250'), ('oName', 'Muriyada Mane')]
# [('f', 'http://www.wikidata.org/entity/Q15721274'), ('oName', 'Mruthyunjaya')]
# [('f', 'http://www.wikidata.org/entity/Q15721789'), ('oName', 'Rudra')]
# [('f', 'http://www.wikidata.org/entity/Q15722883'), ('oName', 'Seethe Alla Savithri')]
# [('f', 'http://www.wikidata.org/entity/Q15723065'), ('oName', 'Swabhimana')]
# [('f', 'http://www.wikidata.org/entity/Q15723163'), ('oName', 'Halli Rambhe Belli Bombe')]
# [('f', 'http://www.wikidata.org/entity/Q15723755'), ('oName', 'Emiti Bi Prema Hue')]
# [('f', 'http://www.wikidata.org/entity/Q15724060'), ('oName', 'Chakabhaunri')]
# [('f', 'http://www.wikidata.org/entity/Q15724100'), ('oName', 'Chinha Achinha')]
# [('f', 'http://www.wikidata.org/entity/Q15724157'), ('oName', 'Jibana Dhara')]
# [('f', 'http://www.wikidata.org/entity/Q15724176'), ('oName', 'Jheeati Sita Pari')]
# [('f', 'http://www.wikidata.org/entity/Q15724178'), ('oName', 'Jhili Mili')]
# [('f', 'http://www.wikidata.org/entity/Q15724242'), ('oName', 'Tu Mo Girlfriend')]
# [('f', 'http://www.wikidata.org/entity/Q15724264'), ('oName', 'Dandabalunga')]
# [('f', 'http://www.wikidata.org/entity/Q15724322'), ('oName', 'Dosti')]
# [('f', 'http://www.wikidata.org/entity/Q15724600'), ('oName', 'Territoriu de bandolerus')]
# [('f', 'http://www.wikidata.org/entity/Q15724695'), ('oName', 'Priyatama')]
# [('f', 'http://www.wikidata.org/entity/Q15724701'), ('oName', 'Prem Bandhan')]
# [('f', 'http://www.wikidata.org/entity/Q15724703'), ('oName', 'Prem weds Priya')]
# [('f', 'http://www.wikidata.org/entity/Q15724730'), ('oName', 'Batasi Jhada')]
# [('f', 'http://www.wikidata.org/entity/Q15724747'), ('oName', 'Barsa My Darling')]
# [('f', 'http://www.wikidata.org/entity/Q15724803'), ('oName', 'Basanti Apa')]
# [('f', 'http://www.wikidata.org/entity/Q15724887'), ('oName', 'Bahu Heba Emiti')]
# [('f', 'http://www.wikidata.org/entity/Q15724998'), ('oName', 'Maa O Mamata')]
# [('f', 'http://www.wikidata.org/entity/Q15725013'), ('oName', 'Maan Abhiman')]
# [('f', 'http://www.wikidata.org/entity/Q15725052'), ('oName', 'Mo Mana Khali Tori Pain')]
# [('f', 'http://www.wikidata.org/entity/Q15725072'), ('oName', 'Jor Jar Mulak Tar')]
# [('f', 'http://www.wikidata.org/entity/Q15725190'), ('oName', 'Shapath')]
# [('f', 'http://www.wikidata.org/entity/Q15725213'), ('oName', 'Sita Rati')]
# [('f', 'http://www.wikidata.org/entity/Q15725225'), ('oName', 'Sharddhanjali')]
# [('f', 'http://www.wikidata.org/entity/Q15725267'), ('oName', 'Santana')]
# [('f', 'http://www.wikidata.org/entity/Q15725300'), ('oName', 'Sakhi Rahila Ae Singha Duara')]
# [('f', 'http://www.wikidata.org/entity/Q15725345'), ('oName', 'Sindura Bindu')]
# [('f', 'http://www.wikidata.org/entity/Q15725358'), ('oName', 'Suna Bhauja')]
# [('f', 'http://www.wikidata.org/entity/Q15725405'), ('oName', 'Hare Krushna Hare Rama')]
# [('f', 'http://www.wikidata.org/entity/Q15725414'), ('oName', 'Haata Dhari Chaaluthaa')]
# [('f', 'http://www.wikidata.org/entity/Q15726151'), ('oName', 'Horseplay')]
# [('f', 'http://www.wikidata.org/entity/Q15728077'), ('oName', "We're Only Human")]
# [('f', 'http://www.wikidata.org/entity/Q15729023'), ('oName', 'Club Sandwich')]
# [('f', 'http://www.wikidata.org/entity/Q15729320'), ('oName', 'El heredero de Casa Pruna')]
# [('f', 'http://www.wikidata.org/entity/Q15729771'), ('oName', 'Stallo: Curse of the Shaman')]
# [('f', 'http://www.wikidata.org/entity/Q15729835'), ('oName', 'Zone Pro Site')]
# [('f', 'http://www.wikidata.org/entity/Q15730627'), ('oName', 'Flamenco Flamenco')]
# [('f', 'http://www.wikidata.org/entity/Q15731589'), ('oName', 'Obhishopto Nighty')]
# [('f', 'http://www.wikidata.org/entity/Q15732538'), ('oName', 'Chapliniana')]
# [('f', 'http://www.wikidata.org/entity/Q15734080'), ('oName', 'Atman')]
# [('f', 'http://www.wikidata.org/entity/Q15735966'), ('oName', 'Dani Daniels: Dare')]
# [('f', 'http://www.wikidata.org/entity/Q15742636'), ('oName', 'In the Sands of Babylon')]
# [('f', 'http://www.wikidata.org/entity/Q15762515'), ('oName', 'Second Origin')]
# [('f', 'http://www.wikidata.org/entity/Q15964719'), ('oName', 'Harakeya Kuri')]
# [('f', 'http://www.wikidata.org/entity/Q16254066'), ('oName', 'Shabdavedhi')]
# [('f', 'http://www.wikidata.org/entity/Q16990973'), ('oName', 'Ratha Sapthami')]
# [('f', 'http://www.wikidata.org/entity/Q17300104'), ('oName', 'Shiva Mecchida Kannappa')]
# [('f', 'http://www.wikidata.org/entity/Q1758112'), ('oName', "Ender's Game")]
# [('f', 'http://www.wikidata.org/entity/Q18201768'), ('oName', 'Mrugaalaya')]
# [('f', 'http://www.wikidata.org/entity/Q19573095'), ('oName', 'Mr. Rajkumar')]
# [('f', 'http://www.wikidata.org/entity/Q19573145'), ('oName', 'Mutthu Ondu Mutthu')]
# [('f', 'http://www.wikidata.org/entity/Q19599701'), ('oName', 'Sri Shaila Mahathme')]
# [('f', 'http://www.wikidata.org/entity/Q19600314'), ('oName', 'Vijayanagarada Veeraputhra')]
# [('f', 'http://www.wikidata.org/entity/Q20724304'), ('oName', 'The Purge: Election Year')]
# [('f', 'http://www.wikidata.org/entity/Q27963105'), ('oName', 'Mallige Hoove')]
# [('f', 'http://www.wikidata.org/entity/Q4804524'), ('oName', 'Ashaant')]
# [('f', 'http://www.wikidata.org/entity/Q4829598'), ('oName', 'Aw Aaakare Aa')]
# [('f', 'http://www.wikidata.org/entity/Q48671658'), ('oName', 'Love Maadi Nodu')]
# [('f', 'http://www.wikidata.org/entity/Q6419692'), ('oName', 'Klanta Aparahna')]
# [('f', 'http://www.wikidata.org/entity/Q7288656'), ('oName', 'Rama Shama Bhama')]
# [('f', 'http://www.wikidata.org/entity/Q7495873'), ('oName', 'Shhh!')]
# [('f', 'http://www.wikidata.org/entity/Q8060324'), ('oName', 'Yuga Purusha')]
# [('f', 'http://www.wikidata.org/entity/Q11727212'), ('oName', 'The Golden Lotus')]
# [('f', 'http://www.wikidata.org/entity/Q15843030'), ('oName', 'Rose Bernd')]
# [('f', 'http://www.wikidata.org/entity/Q15845171'), ('oName', 'The Falcon Out West')]
# [('f', 'http://www.wikidata.org/entity/Q15850483'), ('oName', 'The Fight for Life')]
# [('f', 'http://www.wikidata.org/entity/Q15853884'), ('oName', 'Weit ist der Weg')]
# [('f', 'http://www.wikidata.org/entity/Q15856724'), ('oName', 'Avengers XXX – A Porn Parody')]
# [('f', 'http://www.wikidata.org/entity/Q15857417'), ('oName', 'E.T. XXX – A Dreamzone Parody')]
# [('f', 'http://www.wikidata.org/entity/Q15859580'), ('oName', 'Keller – Teenage Wasteland')]
# [('f', 'http://www.wikidata.org/entity/Q15859668'), ('oName', 'Little Man, What Now?')]
# [('f', 'http://www.wikidata.org/entity/Q15863744'), ('oName', 'Thegidi')]
# 100

# %%
# props of random film (Little Man, What Now?)
queryString = """
SELECT ?p ?name ?o ?oName
WHERE {
   wd:Q15859668 ?p ?o.
   # ?p sc:name ?name.
   # ?o sc:name ?oName.
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P144'), ('name', 'based on'), ('o', 'http://www.wikidata.org/entity/Q1746652'), ('oName', 'Little Man, What Now?')]
# [('p', 'http://www.wikidata.org/prop/direct/P161'), ('name', 'cast member'), ('o', 'http://www.wikidata.org/entity/Q91333'), ('oName', 'Jakob Tiedtke')]
# [('p', 'http://www.wikidata.org/prop/direct/P161'), ('name', 'cast member'), ('o', 'http://www.wikidata.org/entity/Q90022'), ('oName', 'Blandine Ebinger')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('name', 'instance of'), ('o', 'http://www.wikidata.org/entity/Q11424'), ('oName', 'film')]
# [('p', 'http://www.wikidata.org/prop/direct/P136'), ('name', 'genre'), ('o', 'http://www.wikidata.org/entity/Q130232'), ('oName', 'drama')]
# [('p', 'http://www.wikidata.org/prop/direct/P495'), ('name', 'country of origin'), ('o', 'http://www.wikidata.org/entity/Q183'), ('oName', 'Germany')]
# [('p', 'http://www.wikidata.org/prop/direct/P364'), ('name', 'original language of film or TV show'), ('o', 'http://www.wikidata.org/entity/Q188'), ('oName', 'German')]
# [('p', 'http://www.wikidata.org/prop/direct/P462'), ('name', 'color'), ('o', 'http://www.wikidata.org/entity/Q838368'), ('oName', 'black and white')]
# [('p', 'http://www.wikidata.org/prop/direct/P161'), ('name', 'cast member'), ('o', 'http://www.wikidata.org/entity/Q120985'), ('oName', 'Hertha Thiele')]
# [('p', 'http://www.wikidata.org/prop/direct/P58'), ('name', 'screenwriter'), ('o', 'http://www.wikidata.org/entity/Q76184'), ('oName', 'Herbert Selpin')]
# [('p', 'http://www.wikidata.org/prop/direct/P1877'), ('name', 'after a work by'), ('o', 'http://www.wikidata.org/entity/Q76539'), ('oName', 'Hans Fallada')]
# [('p', 'http://www.wikidata.org/prop/direct/P161'), ('name', 'cast member'), ('o', 'http://www.wikidata.org/entity/Q69236'), ('oName', 'Theo Lingen')]
# [('p', 'http://www.wikidata.org/prop/direct/P162'), ('name', 'producer'), ('o', 'http://www.wikidata.org/entity/Q1601419'), ('oName', 'Robert Neppach')]
# [('p', 'http://www.wikidata.org/prop/direct/P161'), ('name', 'cast member'), ('o', 'http://www.wikidata.org/entity/Q86034'), ('oName', 'Hermann Thimig')]
# [('p', 'http://www.wikidata.org/prop/direct/P86'), ('name', 'composer'), ('o', 'http://www.wikidata.org/entity/Q1114648'), ('oName', 'Harald Böhmelt')]
# [('p', 'http://www.wikidata.org/prop/direct/P161'), ('name', 'cast member'), ('o', 'http://www.wikidata.org/entity/Q114558'), ('oName', 'Ida Wüst')]
# [('p', 'http://www.wikidata.org/prop/direct/P344'), ('name', 'director of photography'), ('o', 'http://www.wikidata.org/entity/Q1382764'), ('oName', 'Ewald Daub')]
# [('p', 'http://www.wikidata.org/prop/direct/P161'), ('name', 'cast member'), ('o', 'http://www.wikidata.org/entity/Q90910'), ('oName', 'Viktor de Kowa')]
# [('p', 'http://www.wikidata.org/prop/direct/P161'), ('name', 'cast member'), ('o', 'http://www.wikidata.org/entity/Q98363'), ('oName', 'Fritz Kampers')]
# [('p', 'http://www.wikidata.org/prop/direct/P57'), ('name', 'director'), ('o', 'http://www.wikidata.org/entity/Q88001'), ('oName', 'Fritz Wendhausen')]
# 20

# %%
#drama instance of
queryString = """
SELECT DISTINCT ?o ?oName
WHERE {
    wd:Q130232 wdt:P31 ?o.
   # ?o sc:name ?oName.
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('o', 'http://www.wikidata.org/entity/Q201658'), ('oName', 'film genre')]
# 1

# %%
#all instances of film genre
queryString = """
SELECT DISTINCT ?o ?oName
WHERE {
     # ?o wdt:P31 wd:Q201658.
   # ?o sc:name ?oName.
}
ORDER BY ASC(?oName)
LIMIT 1000
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('o', 'http://www.wikidata.org/entity/Q4674071'), ('oName', 'Acid Western')]
# [('o', 'http://www.wikidata.org/entity/Q108179271'), ('oName', 'Arthouse animation')]
# [('o', 'http://www.wikidata.org/entity/Q223770'), ('oName', 'B movie')]
# [('o', 'http://www.wikidata.org/entity/Q4836991'), ('oName', 'B western')]
# [('o', 'http://www.wikidata.org/entity/Q3461143'), ('oName', 'BDSM film')]
# [('o', 'http://www.wikidata.org/entity/Q31086090'), ('oName', 'Barbarian film')]
# [('o', 'http://www.wikidata.org/entity/Q84041'), ('oName', 'Bavarian porn')]
# [('o', 'http://www.wikidata.org/entity/Q7717463'), ('oName', 'Bible film')]
# [('o', 'http://www.wikidata.org/entity/Q48816645'), ('oName', 'Black film')]
# [('o', 'http://www.wikidata.org/entity/Q93196'), ('oName', 'Bollywood')]
# [('o', 'http://www.wikidata.org/entity/Q16247268'), ('oName', 'Bollywood horror film')]
# [('o', 'http://www.wikidata.org/entity/Q4950139'), ('oName', 'Bourekas film')]
# [('o', 'http://www.wikidata.org/entity/Q849666'), ('oName', 'Brickfilm')]
# [('o', 'http://www.wikidata.org/entity/Q580013'), ('oName', 'Bruceploitation')]
# [('o', 'http://www.wikidata.org/entity/Q30726555'), ('oName', 'Category:Films set in antiquity')]
# [('o', 'http://www.wikidata.org/entity/Q81552104'), ('oName', 'Chakma cinema')]
# [('o', 'http://www.wikidata.org/entity/Q82721965'), ('oName', 'Chakwood')]
# [('o', 'http://www.wikidata.org/entity/Q5070847'), ('oName', 'Chanchada')]
# [('o', 'http://www.wikidata.org/entity/Q5104880'), ('oName', 'Chopsocky')]
# [('o', 'http://www.wikidata.org/entity/Q28026639'), ('oName', 'Christmas film')]
# [('o', 'http://www.wikidata.org/entity/Q2742446'), ('oName', 'Cinéma pur')]
# [('o', 'http://www.wikidata.org/entity/Q1115187'), ('oName', "Commedia all'italiana")]
# [('o', 'http://www.wikidata.org/entity/Q2991565'), ('oName', "Commedia sexy all'italiana")]
# [('o', 'http://www.wikidata.org/entity/Q60753838'), ('oName', 'Computer screen film')]
# [('o', 'http://www.wikidata.org/entity/Q1323308'), ('oName', 'Direct Cinema')]
# [('o', 'http://www.wikidata.org/entity/Q1278107'), ('oName', 'Eastern')]
# [('o', 'http://www.wikidata.org/entity/Q26268098'), ('oName', 'Eastern')]
# [('o', 'http://www.wikidata.org/entity/Q759779'), ('oName', 'Enlightenment film')]
# [('o', 'http://www.wikidata.org/entity/Q6722594'), ('oName', 'Euro War')]
# [('o', 'http://www.wikidata.org/entity/Q5413472'), ('oName', 'European art cinema')]
# [('o', 'http://www.wikidata.org/entity/Q5449041'), ('oName', 'Film à clef')]
# [('o', 'http://www.wikidata.org/entity/Q11859599'), ('oName', 'Findie')]
# [('o', 'http://www.wikidata.org/entity/Q23044991'), ('oName', 'Finnish horror film')]
# [('o', 'http://www.wikidata.org/entity/Q5461696'), ('oName', 'Florida Western')]
# [('o', 'http://www.wikidata.org/entity/Q1352102'), ('oName', 'Free Cinema')]
# [('o', 'http://www.wikidata.org/entity/Q18331260'), ('oName', 'French comedy films')]
# [('o', 'http://www.wikidata.org/entity/Q105320349'), ('oName', 'Gay-related film')]
# [('o', 'http://www.wikidata.org/entity/Q2916932'), ('oName', 'Gendai-geki')]
# [('o', 'http://www.wikidata.org/entity/Q2973158'), ('oName', 'Genre movie')]
# [('o', 'http://www.wikidata.org/entity/Q5551875'), ('oName', 'German underground horror')]
# [('o', 'http://www.wikidata.org/entity/Q5578091'), ('oName', 'Gokudō')]
# [('o', 'http://www.wikidata.org/entity/Q5583970'), ('oName', 'Goona-goona epic')]
# [('o', 'http://www.wikidata.org/entity/Q25230421'), ('oName', 'Gothic romance film')]
# [('o', 'http://www.wikidata.org/entity/Q3778115'), ('oName', 'Gross out')]
# [('o', 'http://www.wikidata.org/entity/Q5622029'), ('oName', 'Guy-cry film')]
# [('o', 'http://www.wikidata.org/entity/Q25636204'), ('oName', 'Haredi cinema')]
# [('o', 'http://www.wikidata.org/entity/Q304538'), ('oName', 'Heimatfilm')]
# [('o', 'http://www.wikidata.org/entity/Q1621121'), ('oName', 'Hitchcockian film')]
# [('o', 'http://www.wikidata.org/entity/Q3772578'), ('oName', 'Home movies')]
# [('o', 'http://www.wikidata.org/entity/Q167776'), ('oName', 'Italian neorealism')]
# [('o', 'http://www.wikidata.org/entity/Q2584671'), ('oName', 'Japanese horror')]
# [('o', 'http://www.wikidata.org/entity/Q629917'), ('oName', 'Jidaigeki')]
# [('o', 'http://www.wikidata.org/entity/Q28164087'), ('oName', 'Jollywood')]
# [('o', 'http://www.wikidata.org/entity/Q1065444'), ('oName', 'Kaiju')]
# [('o', 'http://www.wikidata.org/entity/Q1502766'), ('oName', 'Kammerspielfilm')]
# [('o', 'http://www.wikidata.org/entity/Q5620056'), ('oName', 'Korean horror')]
# [('o', 'http://www.wikidata.org/entity/Q20442589'), ('oName', 'LGBT-related film')]
# [('o', 'http://www.wikidata.org/entity/Q102141681'), ('oName', 'Lesbian and Gay Film')]
# [('o', 'http://www.wikidata.org/entity/Q25975'), ('oName', "Let's Play")]
# [('o', 'http://www.wikidata.org/entity/Q6696549'), ('oName', 'Lucha film')]
# [('o', 'http://www.wikidata.org/entity/Q3028680'), ('oName', 'Masala')]
# [('o', 'http://www.wikidata.org/entity/Q4044177'), ('oName', 'Mexploitation')]
# [('o', 'http://www.wikidata.org/entity/Q11894225'), ('oName', 'Military comedy')]
# [('o', 'http://www.wikidata.org/entity/Q1550219'), ('oName', 'Mo lei tau')]
# [('o', 'http://www.wikidata.org/entity/Q6926334'), ('oName', 'Mouth of Garbage film')]
# [('o', 'http://www.wikidata.org/entity/Q1108032'), ('oName', 'Mumblecore')]
# [('o', 'http://www.wikidata.org/entity/Q6943011'), ('oName', 'Muslim social')]
# [('o', 'http://www.wikidata.org/entity/Q535518'), ('oName', 'Nazi exploitation')]
# [('o', 'http://www.wikidata.org/entity/Q2724311'), ('oName', 'New Queer Cinema')]
# [('o', 'http://www.wikidata.org/entity/Q3344204'), ('oName', 'Northern')]
# [('o', 'http://www.wikidata.org/entity/Q2002987'), ('oName', 'Novo Cinema')]
# [('o', 'http://www.wikidata.org/entity/Q7116678'), ('oName', 'Ozploitation')]
# [('o', 'http://www.wikidata.org/entity/Q7134948'), ('oName', 'Parallel Cinema')]
# [('o', 'http://www.wikidata.org/entity/Q1433443'), ('oName', 'Peplum film genre')]
# [('o', 'http://www.wikidata.org/entity/Q5712461'), ('oName', 'Persian Film')]
# [('o', 'http://www.wikidata.org/entity/Q7234396'), ('oName', 'Postmodernist film')]
# [('o', 'http://www.wikidata.org/entity/Q1456178'), ('oName', 'Prussian film')]
# [('o', 'http://www.wikidata.org/entity/Q3677206'), ('oName', 'Quinqui (film genre)')]
# [('o', 'http://www.wikidata.org/entity/Q107278078'), ('oName', 'Realist film')]
# [('o', 'http://www.wikidata.org/entity/Q268854'), ('oName', 'Red Western')]
# [('o', 'http://www.wikidata.org/entity/Q66425231'), ('oName', 'Redsploitation')]
# [('o', 'http://www.wikidata.org/entity/Q491158'), ('oName', 'Revisionist Western')]
# [('o', 'http://www.wikidata.org/entity/Q7379160'), ('oName', 'Rumberas film')]
# [('o', 'http://www.wikidata.org/entity/Q18355406'), ('oName', 'Satanic film')]
# [('o', 'http://www.wikidata.org/entity/Q2263701'), ('oName', 'Sceneggiata')]
# [('o', 'http://www.wikidata.org/entity/Q2145099'), ('oName', 'Sex report film')]
# [('o', 'http://www.wikidata.org/entity/Q6142791'), ('oName', 'Shinpa')]
# [('o', 'http://www.wikidata.org/entity/Q3482453'), ('oName', 'Shomin-geki')]
# [('o', 'http://www.wikidata.org/entity/Q65088741'), ('oName', 'Skate video')]
# [('o', 'http://www.wikidata.org/entity/Q3964495'), ('oName', 'Somaliwood')]
# [('o', 'http://www.wikidata.org/entity/Q7568398'), ('oName', 'South Seas')]
# [('o', 'http://www.wikidata.org/entity/Q4235011'), ('oName', 'Space Western')]
# [('o', 'http://www.wikidata.org/entity/Q10674355'), ('oName', 'Spanish horror movie')]
# [('o', 'http://www.wikidata.org/entity/Q2000178'), ('oName', 'Telefoni Bianchi')]
# [('o', 'http://www.wikidata.org/entity/Q61117528'), ('oName', 'Ukrainian poetic cinema')]
# [('o', 'http://www.wikidata.org/entity/Q370630'), ('oName', 'Web film')]
# [('o', 'http://www.wikidata.org/entity/Q775169'), ('oName', 'Weird West')]
# [('o', 'http://www.wikidata.org/entity/Q172980'), ('oName', 'Western film')]
# [('o', 'http://www.wikidata.org/entity/Q1669985'), ('oName', 'Wiener Film')]
# [('o', 'http://www.wikidata.org/entity/Q1451709'), ('oName', "Women's cinema")]
# [('o', 'http://www.wikidata.org/entity/Q1117103'), ('oName', 'Z movie')]
# [('o', 'http://www.wikidata.org/entity/Q8066387'), ('oName', 'Zapata Western')]
# [('o', 'http://www.wikidata.org/entity/Q16824564'), ('oName', 'absolute film')]
# [('o', 'http://www.wikidata.org/entity/Q332564'), ('oName', 'abstract film')]
# [('o', 'http://www.wikidata.org/entity/Q2678111'), ('oName', 'action comedy film')]
# [('o', 'http://www.wikidata.org/entity/Q188473'), ('oName', 'action film')]
# [('o', 'http://www.wikidata.org/entity/Q78461348'), ('oName', 'action-adventure film')]
# [('o', 'http://www.wikidata.org/entity/Q108357966'), ('oName', 'actual play')]
# [('o', 'http://www.wikidata.org/entity/Q4677832'), ('oName', 'actuality film')]
# [('o', 'http://www.wikidata.org/entity/Q3249257'), ('oName', 'adult animation')]
# [('o', 'http://www.wikidata.org/entity/Q319221'), ('oName', 'adventure film')]
# [('o', 'http://www.wikidata.org/entity/Q20656352'), ('oName', 'alternate history film')]
# [('o', 'http://www.wikidata.org/entity/Q18466840'), ('oName', 'alternative cinema')]
# [('o', 'http://www.wikidata.org/entity/Q455620'), ('oName', 'amateur film')]
# [('o', 'http://www.wikidata.org/entity/Q56240556'), ('oName', 'amusement ride film')]
# [('o', 'http://www.wikidata.org/entity/Q11857634'), ('oName', 'animal fantasy')]
# [('o', 'http://www.wikidata.org/entity/Q17175676'), ('oName', 'animated cartoon')]
# [('o', 'http://www.wikidata.org/entity/Q4765076'), ('oName', 'animated documentary')]
# [('o', 'http://www.wikidata.org/entity/Q1107'), ('oName', 'anime')]
# [('o', 'http://www.wikidata.org/entity/Q20650540'), ('oName', 'anime film')]
# [('o', 'http://www.wikidata.org/entity/Q336144'), ('oName', 'anthology film')]
# [('o', 'http://www.wikidata.org/entity/Q4774498'), ('oName', 'anti-war film')]
# [('o', 'http://www.wikidata.org/entity/Q47009776'), ('oName', 'apocalyptic film')]
# [('o', 'http://www.wikidata.org/entity/Q1135802'), ('oName', 'art film')]
# [('o', 'http://www.wikidata.org/entity/Q4797626'), ('oName', 'arthouse action film')]
# [('o', 'http://www.wikidata.org/entity/Q3076696'), ('oName', 'association football film')]
# [('o', 'http://www.wikidata.org/entity/Q13209138'), ('oName', 'auteur film')]
# [('o', 'http://www.wikidata.org/entity/Q3072024'), ('oName', 'autobiographical film')]
# [('o', 'http://www.wikidata.org/entity/Q4839755'), ('oName', 'backstage musical')]
# [('o', 'http://www.wikidata.org/entity/Q798555'), ('oName', 'backwoods film')]
# [('o', 'http://www.wikidata.org/entity/Q4840473'), ('oName', 'bad girl movie')]
# [('o', 'http://www.wikidata.org/entity/Q4484381'), ('oName', 'ballet film')]
# [('o', 'http://www.wikidata.org/entity/Q108258724'), ('oName', 'bandy film')]
# [('o', 'http://www.wikidata.org/entity/Q4875794'), ('oName', 'beach party film')]
# [('o', 'http://www.wikidata.org/entity/Q645928'), ('oName', 'biographical film')]
# [('o', 'http://www.wikidata.org/entity/Q5778924'), ('oName', 'black comedy film')]
# [('o', 'http://www.wikidata.org/entity/Q883179'), ('oName', 'blaxploitation')]
# [('o', 'http://www.wikidata.org/entity/Q4925568'), ('oName', 'blaxploitation horror film')]
# [('o', 'http://www.wikidata.org/entity/Q4930081'), ('oName', 'blue film')]
# [('o', 'http://www.wikidata.org/entity/Q102260466'), ('oName', 'body horror film')]
# [('o', 'http://www.wikidata.org/entity/Q895583'), ('oName', 'boxing film')]
# [('o', 'http://www.wikidata.org/entity/Q18398246'), ('oName', 'bromantic comedy')]
# [('o', 'http://www.wikidata.org/entity/Q4984974'), ('oName', 'buddy cop film')]
# [('o', 'http://www.wikidata.org/entity/Q663106'), ('oName', 'buddy film')]
# [('o', 'http://www.wikidata.org/entity/Q1480924'), ('oName', 'cabview film')]
# [('o', 'http://www.wikidata.org/entity/Q1723850'), ('oName', 'cannibal film')]
# [('o', 'http://www.wikidata.org/entity/Q108202399'), ('oName', 'cheerleading films')]
# [('o', 'http://www.wikidata.org/entity/Q2075808'), ('oName', 'chick flick')]
# [('o', 'http://www.wikidata.org/entity/Q4207328'), ('oName', 'child erotica')]
# [('o', 'http://www.wikidata.org/entity/Q2143665'), ('oName', "children's film")]
# [('o', 'http://www.wikidata.org/entity/Q18466908'), ('oName', 'cinema marginal')]
# [('o', 'http://www.wikidata.org/entity/Q1957385'), ('oName', 'cinematic fairy tale')]
# [('o', 'http://www.wikidata.org/entity/Q1092621'), ('oName', 'cinéma vérité')]
# [('o', 'http://www.wikidata.org/entity/Q107022805'), ('oName', 'circus film')]
# [('o', 'http://www.wikidata.org/entity/Q18089617'), ('oName', 'clay animation film')]
# [('o', 'http://www.wikidata.org/entity/Q5145881'), ('oName', 'collage film')]
# [('o', 'http://www.wikidata.org/entity/Q2973149'), ('oName', 'colonial cinema')]
# [('o', 'http://www.wikidata.org/entity/Q157443'), ('oName', 'comedy film')]
# [('o', 'http://www.wikidata.org/entity/Q108466999'), ('oName', 'comedy horror film')]
# [('o', 'http://www.wikidata.org/entity/Q56296585'), ('oName', 'comedy of error')]
# [('o', 'http://www.wikidata.org/entity/Q2991535'), ('oName', 'comedy of intrigue')]
# [('o', 'http://www.wikidata.org/entity/Q5151497'), ('oName', 'comedy of remarriage')]
# [('o', 'http://www.wikidata.org/entity/Q16950433'), ('oName', 'comedy thriller')]
# [('o', 'http://www.wikidata.org/entity/Q859369'), ('oName', 'comedy-drama')]
# [('o', 'http://www.wikidata.org/entity/Q3745400'), ('oName', 'comical film')]
# [('o', 'http://www.wikidata.org/entity/Q102429885'), ('oName', 'coming-of-age film')]
# [('o', 'http://www.wikidata.org/entity/Q455315'), ('oName', 'compilation film')]
# [('o', 'http://www.wikidata.org/entity/Q5156753'), ('oName', 'composite film')]
# [('o', 'http://www.wikidata.org/entity/Q28968258'), ('oName', 'computer-animated film')]
# [('o', 'http://www.wikidata.org/entity/Q430525'), ('oName', 'concert film')]
# [('o', 'http://www.wikidata.org/entity/Q2593937'), ('oName', 'conspiracy fiction')]
# [('o', 'http://www.wikidata.org/entity/Q2907760'), ('oName', 'corporate video')]
# [('o', 'http://www.wikidata.org/entity/Q542475'), ('oName', 'costume drama')]
# [('o', 'http://www.wikidata.org/entity/Q959790'), ('oName', 'crime film')]
# [('o', 'http://www.wikidata.org/entity/Q19367312'), ('oName', 'crime thriller')]
# [('o', 'http://www.wikidata.org/entity/Q1788980'), ('oName', 'crime-comedy film')]
# [('o', 'http://www.wikidata.org/entity/Q7888483'), ('oName', 'crush film')]
# [('o', 'http://www.wikidata.org/entity/Q15804095'), ('oName', 'culture clash comedy')]
# [('o', 'http://www.wikidata.org/entity/Q3072043'), ('oName', 'dance film')]
# [('o', 'http://www.wikidata.org/entity/Q45893900'), ('oName', 'deaf cinema')]
# [('o', 'http://www.wikidata.org/entity/Q25533274'), ('oName', 'detective film')]
# [('o', 'http://www.wikidata.org/entity/Q846544'), ('oName', 'disaster film')]
# [('o', 'http://www.wikidata.org/entity/Q622370'), ('oName', 'docudrama')]
# [('o', 'http://www.wikidata.org/entity/Q472637'), ('oName', 'docufiction')]
# [('o', 'http://www.wikidata.org/entity/Q93204'), ('oName', 'documentary film')]
# [('o', 'http://www.wikidata.org/entity/Q130232'), ('oName', 'drama')]
# [('o', 'http://www.wikidata.org/entity/Q106878648'), ('oName', 'dramatization')]
# [('o', 'http://www.wikidata.org/entity/Q18620604'), ('oName', 'dramatization')]
# [('o', 'http://www.wikidata.org/entity/Q20443008'), ('oName', 'dystopian film')]
# [('o', 'http://www.wikidata.org/entity/Q1153173'), ('oName', 'educational entertainment')]
# [('o', 'http://www.wikidata.org/entity/Q596138'), ('oName', 'educational film')]
# [('o', 'http://www.wikidata.org/entity/Q652256'), ('oName', 'epic film')]
# [('o', 'http://www.wikidata.org/entity/Q599558'), ('oName', 'erotic film')]
# [('o', 'http://www.wikidata.org/entity/Q11356864'), ('oName', 'essay film')]
# [('o', 'http://www.wikidata.org/entity/Q3059309'), ('oName', 'ethnofiction')]
# [('o', 'http://www.wikidata.org/entity/Q1371394'), ('oName', 'ethnographic film')]
# [('o', 'http://www.wikidata.org/entity/Q3677202'), ('oName', 'eurospy film')]
# [('o', 'http://www.wikidata.org/entity/Q790192'), ('oName', 'experimental film')]
# [('o', 'http://www.wikidata.org/entity/Q1067324'), ('oName', 'exploitation film')]
# [('o', 'http://www.wikidata.org/entity/Q1361932'), ('oName', 'family film')]
# [('o', 'http://www.wikidata.org/entity/Q3066315'), ('oName', 'fan edit')]
# [('o', 'http://www.wikidata.org/entity/Q2301591'), ('oName', 'fan film')]
# [('o', 'http://www.wikidata.org/entity/Q95440291'), ('oName', 'fantasy comedy film')]
# [('o', 'http://www.wikidata.org/entity/Q157394'), ('oName', 'fantasy film')]
# [('o', 'http://www.wikidata.org/entity/Q10280356'), ('oName', 'favela movie')]
# [('o', 'http://www.wikidata.org/entity/Q5442753'), ('oName', 'female buddy film')]
# [('o', 'http://www.wikidata.org/entity/Q12912091'), ('oName', 'fiction film')]
# [('o', 'http://www.wikidata.org/entity/Q1257444'), ('oName', 'film adaptation')]
# [('o', 'http://www.wikidata.org/entity/Q52207399'), ('oName', 'film based on a novel')]
# [('o', 'http://www.wikidata.org/entity/Q52207310'), ('oName', 'film based on books')]
# [('o', 'http://www.wikidata.org/entity/Q52162262'), ('oName', 'film based on literature')]
# [('o', 'http://www.wikidata.org/entity/Q5449011'), ('oName', 'film gris')]
# [('o', 'http://www.wikidata.org/entity/Q185867'), ('oName', 'film noir')]
# [('o', 'http://www.wikidata.org/entity/Q29226975'), ('oName', 'film performance')]
# [('o', 'http://www.wikidata.org/entity/Q31836066'), ('oName', 'film portrait')]
# [('o', 'http://www.wikidata.org/entity/Q21401869'), ('oName', 'flashback film')]
# [('o', 'http://www.wikidata.org/entity/Q104902646'), ('oName', 'folk horror')]
# [('o', 'http://www.wikidata.org/entity/Q8564978'), ('oName', 'found film')]
# [('o', 'http://www.wikidata.org/entity/Q3272147'), ('oName', 'found footage')]
# [('o', 'http://www.wikidata.org/entity/Q11298267'), ('oName', 'gambling film')]
# [('o', 'http://www.wikidata.org/entity/Q7444356'), ('oName', 'gangster film')]
# [('o', 'http://www.wikidata.org/entity/Q66948581'), ('oName', 'ghost film')]
# [('o', 'http://www.wikidata.org/entity/Q1332055'), ('oName', 'giallo')]
# [('o', 'http://www.wikidata.org/entity/Q1776156'), ('oName', 'girls with guns')]
# [('o', 'http://www.wikidata.org/entity/Q106117184'), ('oName', 'gongbang')]
# [('o', 'http://www.wikidata.org/entity/Q1538137'), ('oName', 'gore')]
# [('o', 'http://www.wikidata.org/entity/Q5769663'), ('oName', 'gothic horror film')]
# [('o', 'http://www.wikidata.org/entity/Q15055012'), ('oName', 'guerrilla filmmaking')]
# [('o', 'http://www.wikidata.org/entity/Q496523'), ('oName', 'heist film')]
# [('o', 'http://www.wikidata.org/entity/Q5739158'), ('oName', 'heritage film')]
# [('o', 'http://www.wikidata.org/entity/Q622310'), ('oName', 'heroic bloodshed')]
# [('o', 'http://www.wikidata.org/entity/Q2331945'), ('oName', 'high school comedy')]
# [('o', 'http://www.wikidata.org/entity/Q5768328'), ('oName', 'hippie exploitation film')]
# [('o', 'http://www.wikidata.org/entity/Q7168625'), ('oName', 'historical drama')]
# [('o', 'http://www.wikidata.org/entity/Q17013749'), ('oName', 'historical film')]
# [('o', 'http://www.wikidata.org/entity/Q5897543'), ('oName', 'hood film')]
# [('o', 'http://www.wikidata.org/entity/Q5855976'), ('oName', 'horror fantasy')]
# [('o', 'http://www.wikidata.org/entity/Q200092'), ('oName', 'horror film')]
# [('o', 'http://www.wikidata.org/entity/Q3072031'), ('oName', 'hyperlink cinema')]
# [('o', 'http://www.wikidata.org/entity/Q108212954'), ('oName', 'ice hockey film')]
# [('o', 'http://www.wikidata.org/entity/Q459290'), ('oName', 'independent film')]
# [('o', 'http://www.wikidata.org/entity/Q1029920'), ('oName', 'industrial film')]
# [('o', 'http://www.wikidata.org/entity/Q103888910'), ('oName', 'intersex film')]
# [('o', 'http://www.wikidata.org/entity/Q643684'), ('oName', 'jukebox musical')]
# [('o', 'http://www.wikidata.org/entity/Q12549246'), ('oName', 'kinojurnal')]
# [('o', 'http://www.wikidata.org/entity/Q477371'), ('oName', 'kitchen sink realism')]
# [('o', 'http://www.wikidata.org/entity/Q10654943'), ('oName', 'knight film')]
# [('o', 'http://www.wikidata.org/entity/Q6432005'), ('oName', 'korean melodrama')]
# [('o', 'http://www.wikidata.org/entity/Q3072042'), ('oName', 'kung fu film')]
# [('o', 'http://www.wikidata.org/entity/Q643873'), ('oName', 'legal drama')]
# [('o', 'http://www.wikidata.org/entity/Q25110269'), ('oName', 'live-action/animated film')]
# [('o', 'http://www.wikidata.org/entity/Q6729489'), ('oName', 'mafia comedy film')]
# [('o', 'http://www.wikidata.org/entity/Q33130924'), ('oName', 'mafia film')]
# [('o', 'http://www.wikidata.org/entity/Q102706436'), ('oName', 'magic realist film')]
# [('o', 'http://www.wikidata.org/entity/Q1464369'), ('oName', 'making-of')]
# [('o', 'http://www.wikidata.org/entity/Q1033891'), ('oName', 'martial arts film')]
# [('o', 'http://www.wikidata.org/entity/Q107210978'), ('oName', 'maximalist film')]
# [('o', 'http://www.wikidata.org/entity/Q6804274'), ('oName', 'meat pie Western')]
# [('o', 'http://www.wikidata.org/entity/Q3990887'), ('oName', 'medical thriller')]
# [('o', 'http://www.wikidata.org/entity/Q1919632'), ('oName', 'melodrama')]
# [('o', 'http://www.wikidata.org/entity/Q30897819'), ('oName', 'melt movie')]
# [('o', 'http://www.wikidata.org/entity/Q6821792'), ('oName', 'message picture')]
# [('o', 'http://www.wikidata.org/entity/Q6839362'), ('oName', 'microcinema')]
# [('o', 'http://www.wikidata.org/entity/Q638364'), ('oName', 'midnight movie')]
# [('o', 'http://www.wikidata.org/entity/Q107210977'), ('oName', 'minimalist film')]
# [('o', 'http://www.wikidata.org/entity/Q1941707'), ('oName', 'mockbuster')]
# [('o', 'http://www.wikidata.org/entity/Q459435'), ('oName', 'mockumentary')]
# [('o', 'http://www.wikidata.org/entity/Q1474387'), ('oName', 'mondo film')]
# [('o', 'http://www.wikidata.org/entity/Q1342372'), ('oName', 'monster film')]
# [('o', 'http://www.wikidata.org/entity/Q819652'), ('oName', 'mountain film')]
# [('o', 'http://www.wikidata.org/entity/Q20732395'), ('oName', 'mukbang')]
# [('o', 'http://www.wikidata.org/entity/Q1952674'), ('oName', 'mundane science fiction')]
# [('o', 'http://www.wikidata.org/entity/Q1548170'), ('oName', 'musical comedy')]
# [('o', 'http://www.wikidata.org/entity/Q842256'), ('oName', 'musical film')]
# [('o', 'http://www.wikidata.org/entity/Q6942568'), ('oName', 'musical short')]
# [('o', 'http://www.wikidata.org/entity/Q3868655'), ('oName', 'musicarello')]
# [('o', 'http://www.wikidata.org/entity/Q1200678'), ('oName', 'mystery film')]
# [('o', 'http://www.wikidata.org/entity/Q3331891'), ('oName', 'mythopoeia')]
# [('o', 'http://www.wikidata.org/entity/Q2973196'), ('oName', 'narrative cinema')]
# [('o', 'http://www.wikidata.org/entity/Q1696148'), ('oName', 'natural horror film')]
# [('o', 'http://www.wikidata.org/entity/Q1760864'), ('oName', 'nature documentary')]
# [('o', 'http://www.wikidata.org/entity/Q2421031'), ('oName', 'neo-noir')]
# [('o', 'http://www.wikidata.org/entity/Q78528852'), ('oName', 'neo-western')]
# [('o', 'http://www.wikidata.org/entity/Q34848596'), ('oName', 'neon noir')]
# [('o', 'http://www.wikidata.org/entity/Q735478'), ('oName', 'newsreel')]
# [('o', 'http://www.wikidata.org/entity/Q24960157'), ('oName', 'non-fiction film')]
# [('o', 'http://www.wikidata.org/entity/Q4220915'), ('oName', 'novella film')]
# [('o', 'http://www.wikidata.org/entity/Q1377546'), ('oName', 'nunsploitation')]
# [('o', 'http://www.wikidata.org/entity/Q3352071'), ('oName', 'omnibus')]
# [('o', 'http://www.wikidata.org/entity/Q16909344'), ('oName', 'opera film')]
# [('o', 'http://www.wikidata.org/entity/Q7097859'), ('oName', 'operetta film')]
# [('o', 'http://www.wikidata.org/entity/Q4075563'), ('oName', 'outlaw biker film')]
# [('o', 'http://www.wikidata.org/entity/Q7133952'), ('oName', 'paracinema')]
# [('o', 'http://www.wikidata.org/entity/Q622548'), ('oName', 'parody film')]
# [('o', 'http://www.wikidata.org/entity/Q3442060'), ('oName', 'partisan film')]
# [('o', 'http://www.wikidata.org/entity/Q2084909'), ('oName', 'phantom ride')]
# [('o', 'http://www.wikidata.org/entity/Q1194365'), ('oName', 'pink film')]
# [('o', 'http://www.wikidata.org/entity/Q2096633'), ('oName', 'pirate film')]
# [('o', 'http://www.wikidata.org/entity/Q3392969'), ('oName', 'pocket film')]
# [('o', 'http://www.wikidata.org/entity/Q7207520'), ('oName', 'poetry film')]
# [('o', 'http://www.wikidata.org/entity/Q2101714'), ('oName', 'police film')]
# [('o', 'http://www.wikidata.org/entity/Q7210294'), ('oName', 'political drama')]
# [('o', 'http://www.wikidata.org/entity/Q2254211'), ('oName', 'political fiction')]
# [('o', 'http://www.wikidata.org/entity/Q2973201'), ('oName', 'political film')]
# [('o', 'http://www.wikidata.org/entity/Q622291'), ('oName', 'political thriller')]
# [('o', 'http://www.wikidata.org/entity/Q1740789'), ('oName', 'poliziotteschi')]
# [('o', 'http://www.wikidata.org/entity/Q3648909'), ('oName', 'popular-science film')]
# [('o', 'http://www.wikidata.org/entity/Q185529'), ('oName', 'pornographic film')]
# [('o', 'http://www.wikidata.org/entity/Q1341051'), ('oName', 'post-apocalyptic film')]
# [('o', 'http://www.wikidata.org/entity/Q586250'), ('oName', 'prison film')]
# [('o', 'http://www.wikidata.org/entity/Q104880835'), ('oName', 'promotional film')]
# [('o', 'http://www.wikidata.org/entity/Q1935609'), ('oName', 'propaganda film')]
# [('o', 'http://www.wikidata.org/entity/Q8812380'), ('oName', 'pseudo-documentary')]
# [('o', 'http://www.wikidata.org/entity/Q21858363'), ('oName', 'psychedelic film')]
# [('o', 'http://www.wikidata.org/entity/Q7256286'), ('oName', 'psycho-biddy')]
# [('o', 'http://www.wikidata.org/entity/Q63214877'), ('oName', 'psychological drama film')]
# [('o', 'http://www.wikidata.org/entity/Q2125170'), ('oName', 'race film')]
# [('o', 'http://www.wikidata.org/entity/Q2254193'), ('oName', 'rape and revenge film')]
# [('o', 'http://www.wikidata.org/entity/Q7301269'), ('oName', 'reality film')]
# [('o', 'http://www.wikidata.org/entity/Q9259727'), ('oName', 'religious film')]
# [('o', 'http://www.wikidata.org/entity/Q3990885'), ('oName', 'religious thriller')]
# [('o', 'http://www.wikidata.org/entity/Q3396019'), ('oName', 'remodernist film')]
# [('o', 'http://www.wikidata.org/entity/Q124922'), ('oName', 'reportage')]
# [('o', 'http://www.wikidata.org/entity/Q628165'), ('oName', 'road movie')]
# [('o', 'http://www.wikidata.org/entity/Q1800833'), ('oName', 'rockumentary')]
# [('o', 'http://www.wikidata.org/entity/Q1054574'), ('oName', 'romance film')]
# [('o', 'http://www.wikidata.org/entity/Q860626'), ('oName', 'romantic comedy')]
# [('o', 'http://www.wikidata.org/entity/Q12049743'), ('oName', 'romantic horror film')]
# [('o', 'http://www.wikidata.org/entity/Q7362831'), ('oName', 'romantic thriller')]
# [('o', 'http://www.wikidata.org/entity/Q882006'), ('oName', 'rubble film')]
# [('o', 'http://www.wikidata.org/entity/Q22025254'), ('oName', 'sageuk')]
# [('o', 'http://www.wikidata.org/entity/Q169672'), ('oName', 'samurai cinema')]
# [('o', 'http://www.wikidata.org/entity/Q3745430'), ('oName', 'satirical film')]
# [('o', 'http://www.wikidata.org/entity/Q20656232'), ('oName', 'science fiction action film')]
# [('o', 'http://www.wikidata.org/entity/Q20089346'), ('oName', 'science fiction animation')]
# [('o', 'http://www.wikidata.org/entity/Q103925569'), ('oName', 'science fiction anime')]
# [('o', 'http://www.wikidata.org/entity/Q471839'), ('oName', 'science fiction film')]
# [('o', 'http://www.wikidata.org/entity/Q248583'), ('oName', 'screwball comedy film')]
# [('o', 'http://www.wikidata.org/entity/Q7449406'), ('oName', 'semidocumentary')]
# [('o', 'http://www.wikidata.org/entity/Q7751682'), ('oName', 'serial film')]
# [('o', 'http://www.wikidata.org/entity/Q2273331'), ('oName', 'serial killer film')]
# [('o', 'http://www.wikidata.org/entity/Q2991560'), ('oName', 'sex comedy')]
# [('o', 'http://www.wikidata.org/entity/Q2275499'), ('oName', 'sex film')]
# [('o', 'http://www.wikidata.org/entity/Q2292320'), ('oName', 'sexploitation film')]
# [('o', 'http://www.wikidata.org/entity/Q226730'), ('oName', 'silent film')]
# [('o', 'http://www.wikidata.org/entity/Q624771'), ('oName', 'slapstick')]
# [('o', 'http://www.wikidata.org/entity/Q853630'), ('oName', 'slasher film')]
# [('o', 'http://www.wikidata.org/entity/Q7542092'), ('oName', 'slow cinema')]
# [('o', 'http://www.wikidata.org/entity/Q644437'), ('oName', 'snuff film')]
# [('o', 'http://www.wikidata.org/entity/Q16549118'), ('oName', 'social cinema')]
# [('o', 'http://www.wikidata.org/entity/Q95952108'), ('oName', 'social comedy')]
# [('o', 'http://www.wikidata.org/entity/Q7551149'), ('oName', 'social guidance film')]
# [('o', 'http://www.wikidata.org/entity/Q7551315'), ('oName', 'social problem film')]
# [('o', 'http://www.wikidata.org/entity/Q848512'), ('oName', 'sound film')]
# [('o', 'http://www.wikidata.org/entity/Q66914288'), ('oName', 'space adventure film')]
# [('o', 'http://www.wikidata.org/entity/Q3492614'), ('oName', 'space fantasy')]
# [('o', 'http://www.wikidata.org/entity/Q64705787'), ('oName', 'spacesuit films')]
# [('o', 'http://www.wikidata.org/entity/Q212781'), ('oName', 'spaghetti western')]
# [('o', 'http://www.wikidata.org/entity/Q2973181'), ('oName', 'speculative fiction film')]
# [('o', 'http://www.wikidata.org/entity/Q1186399'), ('oName', 'spin-off')]
# [('o', 'http://www.wikidata.org/entity/Q909586'), ('oName', 'splatter film')]
# [('o', 'http://www.wikidata.org/entity/Q7579035'), ('oName', 'sponsored film')]
# [('o', 'http://www.wikidata.org/entity/Q1339864'), ('oName', 'sport film')]
# [('o', 'http://www.wikidata.org/entity/Q2297927'), ('oName', 'spy film')]
# [('o', 'http://www.wikidata.org/entity/Q20649407'), ('oName', 'stag film')]
# [('o', 'http://www.wikidata.org/entity/Q63860397'), ('oName', 'steampunk film')]
# [('o', 'http://www.wikidata.org/entity/Q457832'), ('oName', 'stoner film')]
# [('o', 'http://www.wikidata.org/entity/Q18089587'), ('oName', 'stop-motion animated film')]
# [('o', 'http://www.wikidata.org/entity/Q2973217'), ('oName', 'structural film')]
# [('o', 'http://www.wikidata.org/entity/Q1615638'), ('oName', 'submarine film')]
# [('o', 'http://www.wikidata.org/entity/Q1535153'), ('oName', 'superhero film')]
# [('o', 'http://www.wikidata.org/entity/Q3634883'), ('oName', 'supernatural film')]
# [('o', 'http://www.wikidata.org/entity/Q43911809'), ('oName', 'supernatural horror film')]
# [('o', 'http://www.wikidata.org/entity/Q7645884'), ('oName', 'surf film')]
# [('o', 'http://www.wikidata.org/entity/Q1190502'), ('oName', 'surrealist cinema')]
# [('o', 'http://www.wikidata.org/entity/Q15898171'), ('oName', 'survival film')]
# [('o', 'http://www.wikidata.org/entity/Q11304653'), ('oName', 'suspense film')]
# [('o', 'http://www.wikidata.org/entity/Q222639'), ('oName', 'swashbuckler film')]
# [('o', 'http://www.wikidata.org/entity/Q1146335'), ('oName', 'teen film')]
# [('o', 'http://www.wikidata.org/entity/Q4453959'), ('oName', 'television ballet\u200e')]
# [('o', 'http://www.wikidata.org/entity/Q7699576'), ('oName', 'tendency film')]
# [('o', 'http://www.wikidata.org/entity/Q2484376'), ('oName', 'thriller film')]
# [('o', 'http://www.wikidata.org/entity/Q104765957'), ('oName', 'time-travel film')]
# [('o', 'http://www.wikidata.org/entity/Q275934'), ('oName', 'tokusatsu')]
# [('o', 'http://www.wikidata.org/entity/Q2445146'), ('oName', 'torture porn')]
# [('o', 'http://www.wikidata.org/entity/Q28968511'), ('oName', 'traditionally animated film')]
# [('o', 'http://www.wikidata.org/entity/Q7832972'), ('oName', 'training film')]
# [('o', 'http://www.wikidata.org/entity/Q104097073'), ('oName', 'transgender film')]
# [('o', 'http://www.wikidata.org/entity/Q2670855'), ('oName', 'travel documentary')]
# [('o', 'http://www.wikidata.org/entity/Q4461646'), ('oName', 'travelogue')]
# [('o', 'http://www.wikidata.org/entity/Q22981906'), ('oName', 'treasure hunt film')]
# [('o', 'http://www.wikidata.org/entity/Q3072039'), ('oName', 'trial film')]
# [('o', 'http://www.wikidata.org/entity/Q20002651'), ('oName', 'trick film')]
# [('o', 'http://www.wikidata.org/entity/Q7841716'), ('oName', 'trigger film')]
# [('o', 'http://www.wikidata.org/entity/Q2007999'), ('oName', 'underground film')]
# [('o', 'http://www.wikidata.org/entity/Q2137852'), ('oName', 'vampire film')]
# [('o', 'http://www.wikidata.org/entity/Q24905792'), ('oName', 'vansploitation')]
# [('o', 'http://www.wikidata.org/entity/Q48773471'), ('oName', 'video essay')]
# [('o', 'http://www.wikidata.org/entity/Q2642760'), ('oName', 'vigilante film')]
# [('o', 'http://www.wikidata.org/entity/Q369747'), ('oName', 'war film')]
# [('o', 'http://www.wikidata.org/entity/Q5258881'), ('oName', 'werewolf film')]
# [('o', 'http://www.wikidata.org/entity/Q83646243'), ('oName', 'western animation')]
# [('o', 'http://www.wikidata.org/entity/Q8030668'), ('oName', "woman's film")]
# [('o', 'http://www.wikidata.org/entity/Q583768'), ('oName', 'women in prison film')]
# [('o', 'http://www.wikidata.org/entity/Q108202384'), ('oName', "women's association football film")]
# [('o', 'http://www.wikidata.org/entity/Q108202392'), ('oName', "women's sports film")]
# [('o', 'http://www.wikidata.org/entity/Q15858553'), ('oName', 'wuxia film')]
# [('o', 'http://www.wikidata.org/entity/Q731194'), ('oName', 'yakuza film')]
# [('o', 'http://www.wikidata.org/entity/Q1747837'), ('oName', 'zombie comedy')]
# [('o', 'http://www.wikidata.org/entity/Q3072049'), ('oName', 'zombie film')]
# 410

# %%
#film genre instance of
queryString = """
SELECT DISTINCT ?o ?oName
WHERE {
     wd:Q201658 wdt:P31 ?o.
   # ?o sc:name ?oName.
}
ORDER BY ASC(?oName)
LIMIT 1000
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('o', 'http://www.wikidata.org/entity/Q19361238'), ('oName', 'Wikidata metaclass')]
# 1

# %%
#prova finale
queryString = """
SELECT DISTINCT ?comp ?name (COUNT(?film) AS ?NcrimeFilm)
WHERE {
    # ?film wdt:P136 wd:Q959790; #genre crime film
        wdt:P272 ?comp.        #produced by comp
    VALUES ?prodComp {wd:Q10689397 wd:Q1762059} #either tv or film (resp.) prod comp
    # ?comp wdt:P31 ?prodComp;
        sc:name ?name.
}
GROUP BY ?comp ?name
ORDER BY DESC(?NcrimeFilm)
LIMIT 5
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('comp', 'http://www.wikidata.org/entity/Q434841'), ('name', '20th Century Studios'), ('NcrimeFilm', '180')]
# [('comp', 'http://www.wikidata.org/entity/Q126399'), ('name', 'Warner Bros.'), ('NcrimeFilm', '164')]
# [('comp', 'http://www.wikidata.org/entity/Q186941'), ('name', 'Columbia Pictures'), ('NcrimeFilm', '118')]
# [('comp', 'http://www.wikidata.org/entity/Q168383'), ('name', 'Universal Pictures'), ('NcrimeFilm', '113')]
# [('comp', 'http://www.wikidata.org/entity/Q179200'), ('name', 'Metro-Goldwyn-Mayer'), ('NcrimeFilm', '112')]
# 5

# %% [markdown]
# Final query for this task

# %%
#top 5 crime film producers
queryString = """
SELECT DISTINCT ?iri ?name (COUNT(?film) AS ?NcrimeFilm)
WHERE {
    # ?film wdt:P136 wd:Q959790; #genre crime film
        wdt:P272 ?iri.        #produced by comp (iri)
    VALUES ?prodComp {wd:Q10689397 wd:Q1762059} #either tv or film (resp.) prod comp
    # ?iri wdt:P31 ?prodComp;
        sc:name ?name.
}
GROUP BY ?iri ?name
ORDER BY DESC(?NcrimeFilm)
LIMIT 5
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('iri', 'http://www.wikidata.org/entity/Q434841'), ('name', '20th Century Studios'), ('NcrimeFilm', '180')]
# [('iri', 'http://www.wikidata.org/entity/Q126399'), ('name', 'Warner Bros.'), ('NcrimeFilm', '164')]
# [('iri', 'http://www.wikidata.org/entity/Q186941'), ('name', 'Columbia Pictures'), ('NcrimeFilm', '118')]
# [('iri', 'http://www.wikidata.org/entity/Q168383'), ('name', 'Universal Pictures'), ('NcrimeFilm', '113')]
# [('iri', 'http://www.wikidata.org/entity/Q179200'), ('name', 'Metro-Goldwyn-Mayer'), ('NcrimeFilm', '112')]
# 5

# %% [markdown]
# ## Task 6
# Find the company (amongst television production company and film production company) which distributed more films (of any kind of film genre) that they did not produce (the result set must be a list of triples company IRI, label and #film).

# %%
#prova finale
queryString = """
SELECT DISTINCT (?comp AS ?iri) ?name (COUNT(?film) AS ?Nfilm)
WHERE {    
    VALUES ?prodComp {wd:Q10689397 wd:Q1762059} #either tv or film (resp.) prod comp
    # ?comp wdt:P31 ?prodComp;
        sc:name ?name.
    # ?film wdt:P750 ?comp.                     #distributed by comp
    FILTER NOT EXISTS { ?film wdt:P272 ?comp} #not produced by comp
}
GROUP BY ?comp ?name
ORDER BY DESC(?Nfilm)
LIMIT 1
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('iri', 'http://www.wikidata.org/entity/Q907311'), ('name', 'Netflix'), ('Nfilm', '26171')]
# 1

# %% [markdown]
# Final query for this task

# %%
#company with most distributed films not produced by them
queryString = """
SELECT DISTINCT (?comp AS ?iri) ?name (COUNT(?film) AS ?Nfilm)
WHERE {    
    VALUES ?prodComp {wd:Q10689397 wd:Q1762059} #either tv or film (resp.) prod comp
    # ?comp wdt:P31 ?prodComp;
        sc:name ?name.
    # ?film wdt:P750 ?comp.                     #distributed by comp
    FILTER NOT EXISTS { ?film wdt:P272 ?comp} #not produced by comp
}
GROUP BY ?comp ?name
ORDER BY DESC(?Nfilm)
LIMIT 1
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('iri', 'http://www.wikidata.org/entity/Q907311'), ('name', 'Netflix'), ('Nfilm', '26171')]
# 1

# %% [markdown]
# ## Task 7
# Find how many company are listed in every stock exchange market (the result set must be a list of triples stock exchange IRI, label and #companies).

# %%
#all stock exchange markets
queryString = """
SELECT DISTINCT ?o ?name
WHERE {    
    # ?comp wdt:P414 ?o.
    # ?o sc:name ?name.
}

LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('o', 'http://www.wikidata.org/entity/Q1526647'), ('name', 'Philippine Stock Exchange')]
# [('o', 'http://www.wikidata.org/entity/Q43335'), ('name', 'Bursa Malaysia')]
# [('o', 'http://www.wikidata.org/entity/Q2415561'), ('name', 'Euronext Lisbon')]
# [('o', 'http://www.wikidata.org/entity/Q891561'), ('name', 'Santiago Stock Exchange')]
# [('o', 'http://www.wikidata.org/entity/Q550050'), ('name', 'Belgrade Stock Exchange')]
# [('o', 'http://www.wikidata.org/entity/Q59551'), ('name', 'Warsaw Stock Exchange')]
# [('o', 'http://www.wikidata.org/entity/Q74662'), ('name', 'Fundsquare Market Infrastructure')]
# [('o', 'http://www.wikidata.org/entity/Q851259'), ('name', 'Budapest Stock Exchange')]
# [('o', 'http://www.wikidata.org/entity/Q698535'), ('name', 'Wiener Börse')]
# [('o', 'http://www.wikidata.org/entity/Q3349831'), ('name', 'Chittagong Stock Exchange')]
# [('o', 'http://www.wikidata.org/entity/Q66320'), ('name', 'over-the-counter trading')]
# [('o', 'http://www.wikidata.org/entity/Q491503'), ('name', 'KOSDAQ')]
# [('o', 'http://www.wikidata.org/entity/Q495372'), ('name', 'Korea Exchange')]
# [('o', 'http://www.wikidata.org/entity/Q661834'), ('name', 'SIX Swiss Exchange')]
# [('o', 'http://www.wikidata.org/entity/Q819468'), ('name', 'Xetra')]
# [('o', 'http://www.wikidata.org/entity/Q1666934'), ('name', 'International Standard Industrial Classification')]
# [('o', 'http://www.wikidata.org/entity/Q617426'), ('name', 'Bolsa de Madrid')]
# [('o', 'http://www.wikidata.org/entity/Q2306284'), ('name', 'Saint Petersburg Stock Exchange')]
# [('o', 'http://www.wikidata.org/entity/Q627019'), ('name', 'New Zealand Exchange')]
# [('o', 'http://www.wikidata.org/entity/Q842108'), ('name', 'Euronext')]
# [('o', 'http://www.wikidata.org/entity/Q1752646'), ('name', 'Prague Stock Exchange')]
# [('o', 'http://www.wikidata.org/entity/Q7386994'), ('name', 'S&P 400')]
# [('o', 'http://www.wikidata.org/entity/Q151139'), ('name', 'Frankfurt Stock Exchange')]
# [('o', 'http://www.wikidata.org/entity/Q171240'), ('name', 'London Stock Exchange')]
# [('o', 'http://www.wikidata.org/entity/Q183'), ('name', 'Germany')]
# [('o', 'http://www.wikidata.org/entity/Q1930860'), ('name', 'OTC Markets Group')]
# [('o', 'http://www.wikidata.org/entity/Q217475'), ('name', 'Tokyo Stock Exchange')]
# [('o', 'http://www.wikidata.org/entity/Q490'), ('name', 'Milan')]
# [('o', 'http://www.wikidata.org/entity/Q627514'), ('name', 'JSE Limited')]
# [('o', 'http://www.wikidata.org/entity/Q82059'), ('name', 'NASDAQ')]
# [('o', 'http://www.wikidata.org/entity/Q242345'), ('name', 'S&P 500')]
# [('o', 'http://www.wikidata.org/entity/Q507306'), ('name', 'NASDAQ-100')]
# [('o', 'http://www.wikidata.org/entity/Q13677'), ('name', 'New York Stock Exchange')]
# [('o', 'http://www.wikidata.org/entity/Q13683'), ('name', 'NYSE Euronext')]
# [('o', 'http://www.wikidata.org/entity/Q496672'), ('name', 'Hong Kong Stock Exchange')]
# [('o', 'http://www.wikidata.org/entity/Q732670'), ('name', 'Australian Securities Exchange')]
# [('o', 'http://www.wikidata.org/entity/Q739514'), ('name', 'Shanghai Stock Exchange')]
# [('o', 'http://www.wikidata.org/entity/Q936563'), ('name', 'Italian Bourse')]
# [('o', 'http://www.wikidata.org/entity/Q1022714'), ('name', 'CAC Small')]
# [('o', 'http://www.wikidata.org/entity/Q1146518'), ('name', 'Euronext Brussels')]
# [('o', 'http://www.wikidata.org/entity/Q2385849'), ('name', 'Euronext Paris')]
# [('o', 'http://www.wikidata.org/entity/Q478720'), ('name', 'Euronext Amsterdam')]
# [('o', 'http://www.wikidata.org/entity/Q517750'), ('name', 'Shenzhen Stock Exchange')]
# [('o', 'http://www.wikidata.org/entity/Q4202719'), ('name', 'Valencia Stock Exchange')]
# [('o', 'http://www.wikidata.org/entity/Q4202960'), ('name', 'Bolsa de Valores de Barcelona')]
# [('o', 'http://www.wikidata.org/entity/Q4890307'), ('name', 'Bilbao Stock Exchange')]
# [('o', 'http://www.wikidata.org/entity/Q891559'), ('name', 'Mexican Stock Exchange')]
# [('o', 'http://www.wikidata.org/entity/Q1019983'), ('name', 'Nasdaq Copenhagen')]
# [('o', 'http://www.wikidata.org/entity/Q1973019'), ('name', 'Dubai Financial Market')]
# [('o', 'http://www.wikidata.org/entity/Q4513926'), ('name', 'Montenegro Stock Exchange')]
# [('o', 'http://www.wikidata.org/entity/Q1984912'), ('name', 'PFTS Ukraine Stock Exchange')]
# [('o', 'http://www.wikidata.org/entity/Q4164626'), ('name', 'Kuwait Stock Exchange')]
# [('o', 'http://www.wikidata.org/entity/Q2632892'), ('name', 'Moscow Exchange')]
# [('o', 'http://www.wikidata.org/entity/Q818723'), ('name', 'Toronto Stock Exchange')]
# [('o', 'http://www.wikidata.org/entity/Q140388'), ('name', 'Zagreb Stock Exchange')]
# [('o', 'http://www.wikidata.org/entity/Q144458'), ('name', 'Euronext Dublin')]
# [('o', 'http://www.wikidata.org/entity/Q548621'), ('name', 'Taiwan Stock Exchange')]
# [('o', 'http://www.wikidata.org/entity/Q1188840'), ('name', 'Nagoya Stock Exchange')]
# [('o', 'http://www.wikidata.org/entity/Q1320224'), ('name', 'Osaka Exchange')]
# [('o', 'http://www.wikidata.org/entity/Q796297'), ('name', 'B3')]
# [('o', 'http://www.wikidata.org/entity/Q1196314'), ('name', 'stock')]
# [('o', 'http://www.wikidata.org/entity/Q755341'), ('name', 'Athens Exchange')]
# [('o', 'http://www.wikidata.org/entity/Q1019992'), ('name', 'Nasdaq Stockholm')]
# [('o', 'http://www.wikidata.org/entity/Q751361'), ('name', 'Hong Kong Exchanges and Clearing Limited')]
# [('o', 'http://www.wikidata.org/entity/Q1330208'), ('name', 'Stock Exchange of Thailand')]
# [('o', 'http://www.wikidata.org/entity/Q1344438'), ('name', 'Russian Trading System')]
# [('o', 'http://www.wikidata.org/entity/Q681683'), ('name', 'Börse München')]
# [('o', 'http://www.wikidata.org/entity/Q1132158'), ('name', 'OMX AB')]
# [('o', 'http://www.wikidata.org/entity/Q1734773'), ('name', 'Kazakhstan Stock Exchange')]
# [('o', 'http://www.wikidata.org/entity/Q1515558'), ('name', 'Singapore Exchange')]
# [('o', 'http://www.wikidata.org/entity/Q2006583'), ('name', 'Tadawul')]
# [('o', 'http://www.wikidata.org/entity/Q1624698'), ('name', 'Riga Stock Exchange')]
# [('o', 'http://www.wikidata.org/entity/Q1421543'), ('name', 'Moscow Interbank Currency Exchange')]
# [('o', 'http://www.wikidata.org/entity/Q1805567'), ('name', 'Tehran Stock Exchange')]
# [('o', 'http://www.wikidata.org/entity/Q178513'), ('name', 'Paris Bourse')]
# [('o', 'http://www.wikidata.org/entity/Q4992224'), ('name', 'Palestine Exchange')]
# [('o', 'http://www.wikidata.org/entity/Q5598539'), ('name', 'Taipei Exchange')]
# [('o', 'http://www.wikidata.org/entity/Q1974408'), ('name', 'Dhaka Stock Exchange')]
# [('o', 'http://www.wikidata.org/entity/Q6529599'), ('name', 'Nepal Stock Exchange')]
# [('o', 'http://www.wikidata.org/entity/Q12721279'), ('name', 'Australian Stock Exchange')]
# [('o', 'http://www.wikidata.org/entity/Q638740'), ('name', 'National Stock Exchange of India')]
# [('o', 'http://www.wikidata.org/entity/Q2888321'), ('name', 'Cyprus Stock Exchange')]
# [('o', 'http://www.wikidata.org/entity/Q1507974'), ('name', 'Tel Aviv Stock Exchange')]
# [('o', 'http://www.wikidata.org/entity/Q909158'), ('name', 'Oslo Stock Exchange')]
# [('o', 'http://www.wikidata.org/entity/Q12048417'), ('name', 'RM-SYSTÉM, česká burza cenných papírů')]
# [('o', 'http://www.wikidata.org/entity/Q1407995'), ('name', 'Borsa Istanbul')]
# [('o', 'http://www.wikidata.org/entity/Q11093491'), ('name', 'Sapporo Securities Exchange')]
# [('o', 'http://www.wikidata.org/entity/Q11240145'), ('name', 'Q-Board')]
# [('o', 'http://www.wikidata.org/entity/Q11340130'), ('name', 'Mothers')]
# [('o', 'http://www.wikidata.org/entity/Q23308122'), ('name', 'National Equities Exchange and Quotations')]
# [('o', 'http://www.wikidata.org/entity/Q157852'), ('name', 'Deutsche Börse')]
# [('o', 'http://www.wikidata.org/entity/Q581755'), ('name', 'Nasdaq Helsinki')]
# [('o', 'http://www.wikidata.org/entity/Q1661737'), ('name', 'Indonesia Stock Exchange')]
# [('o', 'http://www.wikidata.org/entity/Q2573852'), ('name', 'Jakarta Stock Exchange')]
# [('o', 'http://www.wikidata.org/entity/Q3117577'), ('name', 'TMX Group')]
# [('o', 'http://www.wikidata.org/entity/Q5566927'), ('name', 'Glasgow Stock Exchange')]
# [('o', 'http://www.wikidata.org/entity/Q1683760'), ('name', 'JASDAQ Securities Exchange')]
# [('o', 'http://www.wikidata.org/entity/Q1648198'), ('name', 'Qatar Exchange')]
# [('o', 'http://www.wikidata.org/entity/Q638398'), ('name', 'Bombay Stock Exchange')]
# [('o', 'http://www.wikidata.org/entity/Q495364'), ('name', 'Korea Stock Exchange')]
# 100

# %%
#prova finale
queryString = """
SELECT DISTINCT (?sem AS ?iri) ?name (COUNT(?comp) AS ?Ncompanies)
WHERE {    
    VALUES ?prodComp {wd:Q10689397 wd:Q1762059} #either tv or film (resp.) prod comp
    # ?comp wdt:P31 ?prodComp;
        wdt:P414 ?sem. #sem is stock exchange market
    # ?sem sc:name ?name.
}
GROUP BY ?sem ?name
ORDER BY DESC(?Ncompanies)
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('iri', 'http://www.wikidata.org/entity/Q13677'), ('name', 'New York Stock Exchange'), ('Ncompanies', '5')]
# [('iri', 'http://www.wikidata.org/entity/Q82059'), ('name', 'NASDAQ'), ('Ncompanies', '4')]
# [('iri', 'http://www.wikidata.org/entity/Q1661737'), ('name', 'Indonesia Stock Exchange'), ('Ncompanies', '2')]
# [('iri', 'http://www.wikidata.org/entity/Q496672'), ('name', 'Hong Kong Stock Exchange'), ('Ncompanies', '2')]
# [('iri', 'http://www.wikidata.org/entity/Q217475'), ('name', 'Tokyo Stock Exchange'), ('Ncompanies', '2')]
# [('iri', 'http://www.wikidata.org/entity/Q732670'), ('name', 'Australian Securities Exchange'), ('Ncompanies', '1')]
# [('iri', 'http://www.wikidata.org/entity/Q818723'), ('name', 'Toronto Stock Exchange'), ('Ncompanies', '1')]
# 7

# %%
#all tv or film prod companies
queryString = """
SELECT DISTINCT ?comp ?name 
WHERE {    
    VALUES ?prodComp {wd:Q10689397 wd:Q1762059} #either tv or film (resp.) prod comp
    # ?comp wdt:P31 ?prodComp;        
        sc:name ?name.
}

LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('comp', 'http://www.wikidata.org/entity/Q1124579'), ('name', 'Condor Films')]
# [('comp', 'http://www.wikidata.org/entity/Q20724376'), ('name', 'CC&C – Clarke Costelle et Cie')]
# [('comp', 'http://www.wikidata.org/entity/Q17086011'), ('name', 'Prometheus Entertainment')]
# [('comp', 'http://www.wikidata.org/entity/Q17088846'), ('name', 'Spring Films')]
# [('comp', 'http://www.wikidata.org/entity/Q17090410'), ('name', 'Tribe Pictures')]
# [('comp', 'http://www.wikidata.org/entity/Q17090464'), ('name', 'Trump Productions')]
# [('comp', 'http://www.wikidata.org/entity/Q17090873'), ('name', 'Mosdeux')]
# [('comp', 'http://www.wikidata.org/entity/Q18155354'), ('name', 'TSG Entertainment')]
# [('comp', 'http://www.wikidata.org/entity/Q477943'), ('name', 'Bad Hat Harry Productions')]
# [('comp', 'http://www.wikidata.org/entity/Q5433853'), ('name', 'Fangoria Films')]
# [('comp', 'http://www.wikidata.org/entity/Q7548638'), ('name', 'Snowfort Pictures')]
# [('comp', 'http://www.wikidata.org/entity/Q17201386'), ('name', "L'Altrofilm")]
# [('comp', 'http://www.wikidata.org/entity/Q17305142'), ('name', 'Red Wagon Entertainment')]
# [('comp', 'http://www.wikidata.org/entity/Q17343527'), ('name', 'Runteldat Entertainment')]
# [('comp', 'http://www.wikidata.org/entity/Q28412462'), ('name', 'Yung Hwa Motion Picture Industries')]
# [('comp', 'http://www.wikidata.org/entity/Q22032421'), ('name', 'Dovrefilm')]
# [('comp', 'http://www.wikidata.org/entity/Q16711321'), ('name', 'Cinema Foundation of Russia')]
# [('comp', 'http://www.wikidata.org/entity/Q20870079'), ('name', 'Savage Film')]
# [('comp', 'http://www.wikidata.org/entity/Q21964532'), ('name', 'Ziegler Film')]
# [('comp', 'http://www.wikidata.org/entity/Q3314282'), ('name', 'Mille et une productions')]
# [('comp', 'http://www.wikidata.org/entity/Q3500954'), ('name', 'Orange studio')]
# [('comp', 'http://www.wikidata.org/entity/Q5582469'), ('name', 'Good Clean Fun LLC')]
# [('comp', 'http://www.wikidata.org/entity/Q103981741'), ('name', 'Glukoza Production')]
# [('comp', 'http://www.wikidata.org/entity/Q1337744'), ('name', 'GPO Film Unit')]
# [('comp', 'http://www.wikidata.org/entity/Q1975431'), ('name', 'Kyrgyzfilm')]
# [('comp', 'http://www.wikidata.org/entity/Q21787624'), ('name', 'Infinity Film & TV Productions')]
# [('comp', 'http://www.wikidata.org/entity/Q21940019'), ('name', 'Nordic Screen Development')]
# [('comp', 'http://www.wikidata.org/entity/Q27646824'), ('name', 'Kaap Holland Film')]
# [('comp', 'http://www.wikidata.org/entity/Q29836837'), ('name', 'Dombey Street Productions')]
# [('comp', 'http://www.wikidata.org/entity/Q22037643'), ('name', 'Capitol Produksjon')]
# [('comp', 'http://www.wikidata.org/entity/Q22080360'), ('name', 'Friday Film House')]
# [('comp', 'http://www.wikidata.org/entity/Q30589038'), ('name', 'Fremulon')]
# [('comp', 'http://www.wikidata.org/entity/Q17300077'), ('name', 'Temple Hill Entertainment')]
# [('comp', 'http://www.wikidata.org/entity/Q24897318'), ('name', 'Providence Pictures')]
# [('comp', 'http://www.wikidata.org/entity/Q3523524'), ('name', 'Thelma Films')]
# [('comp', 'http://www.wikidata.org/entity/Q85983145'), ('name', 'Filmmaker R&K')]
# [('comp', 'http://www.wikidata.org/entity/Q2367528'), ('name', 'Superfilm')]
# [('comp', 'http://www.wikidata.org/entity/Q26210002'), ('name', '7Art')]
# [('comp', 'http://www.wikidata.org/entity/Q3232650'), ('name', 'Les Films du Kiosque')]
# [('comp', 'http://www.wikidata.org/entity/Q6745872'), ('name', 'Mammoth Screen')]
# [('comp', 'http://www.wikidata.org/entity/Q1529957'), ('name', 'Leonine Holding')]
# [('comp', 'http://www.wikidata.org/entity/Q1868978'), ('name', 'London Films')]
# [('comp', 'http://www.wikidata.org/entity/Q3149951'), ('name', 'ITC Entertainment')]
# [('comp', 'http://www.wikidata.org/entity/Q5204823'), ('name', 'DEJ Productions')]
# [('comp', 'http://www.wikidata.org/entity/Q676498'), ('name', 'CCC Film')]
# [('comp', 'http://www.wikidata.org/entity/Q107391544'), ('name', 'Curtleigh Productions')]
# [('comp', 'http://www.wikidata.org/entity/Q12006943'), ('name', 'Tordenfilm')]
# [('comp', 'http://www.wikidata.org/entity/Q12594195'), ('name', 'Lotte Cultureworks')]
# [('comp', 'http://www.wikidata.org/entity/Q17063093'), ('name', 'Myung Films')]
# [('comp', 'http://www.wikidata.org/entity/Q17345505'), ('name', 'Jerry Weintraub Productions')]
# [('comp', 'http://www.wikidata.org/entity/Q17346576'), ('name', 'Largo Entertainment')]
# [('comp', 'http://www.wikidata.org/entity/Q17417784'), ('name', 'Marc Platt Productions')]
# [('comp', 'http://www.wikidata.org/entity/Q22280492'), ('name', 'Kisi Production')]
# [('comp', 'http://www.wikidata.org/entity/Q2756503'), ('name', 'Gaumont-British Picture Corporation')]
# [('comp', 'http://www.wikidata.org/entity/Q3005562'), ('name', 'Cruise/Wagner Productions')]
# [('comp', 'http://www.wikidata.org/entity/Q4353408'), ('name', 'EMI Films')]
# [('comp', 'http://www.wikidata.org/entity/Q490687'), ('name', 'MBC Game')]
# [('comp', 'http://www.wikidata.org/entity/Q5018052'), ('name', 'Cake Entertainment')]
# [('comp', 'http://www.wikidata.org/entity/Q5617764'), ('name', 'Gullane Entertainment PLC')]
# [('comp', 'http://www.wikidata.org/entity/Q626185'), ('name', 'SHOWBOX Co., Ltd.')]
# [('comp', 'http://www.wikidata.org/entity/Q7752106'), ('name', 'The Montecito Picture Company')]
# [('comp', 'http://www.wikidata.org/entity/Q7860855'), ('name', 'Type A Films')]
# [('comp', 'http://www.wikidata.org/entity/Q85971242'), ('name', 'JK Film')]
# [('comp', 'http://www.wikidata.org/entity/Q90013629'), ('name', 'Claussen & Wöbke Filmproduktion')]
# [('comp', 'http://www.wikidata.org/entity/Q100699785'), ('name', 'Ö-Filmproduktion Löprich & Schlösser')]
# [('comp', 'http://www.wikidata.org/entity/Q1111024'), ('name', 'MTV Films')]
# [('comp', 'http://www.wikidata.org/entity/Q5369517'), ('name', 'Embassy Pictures')]
# [('comp', 'http://www.wikidata.org/entity/Q615141'), ('name', 'Outlaw Productions')]
# [('comp', 'http://www.wikidata.org/entity/Q624886'), ('name', 'FilmDistrict')]
# [('comp', 'http://www.wikidata.org/entity/Q6414157'), ('name', 'Kino International')]
# [('comp', 'http://www.wikidata.org/entity/Q645478'), ('name', 'Mutant Enemy Productions')]
# [('comp', 'http://www.wikidata.org/entity/Q7276847'), ('name', 'RIVR Media')]
# [('comp', 'http://www.wikidata.org/entity/Q89875316'), ('name', 'Boje Buck Produktion')]
# [('comp', 'http://www.wikidata.org/entity/Q1161600'), ('name', 'Mafilm')]
# [('comp', 'http://www.wikidata.org/entity/Q17386235'), ('name', 'Neo Art & Logic')]
# [('comp', 'http://www.wikidata.org/entity/Q18331625'), ('name', 'Cerito Films')]
# [('comp', 'http://www.wikidata.org/entity/Q3098606'), ('name', 'Gary Sanchez Productions')]
# [('comp', 'http://www.wikidata.org/entity/Q3503770'), ('name', 'Bally Sports Sun')]
# [('comp', 'http://www.wikidata.org/entity/Q3999144'), ('name', 'Triumph Films')]
# [('comp', 'http://www.wikidata.org/entity/Q4985726'), ('name', 'Buffalo Gal Pictures')]
# [('comp', 'http://www.wikidata.org/entity/Q5376047'), ('name', 'Endemol Shine UK')]
# [('comp', 'http://www.wikidata.org/entity/Q771272'), ('name', 'Worldvision Enterprises')]
# [('comp', 'http://www.wikidata.org/entity/Q78623145'), ('name', 'UGC Images')]
# [('comp', 'http://www.wikidata.org/entity/Q78631420'), ('name', 'Sogecine')]
# [('comp', 'http://www.wikidata.org/entity/Q79395710'), ('name', 'Himenoptero')]
# [('comp', 'http://www.wikidata.org/entity/Q79395789'), ('name', 'Eyescreen')]
# [('comp', 'http://www.wikidata.org/entity/Q8204054'), ('name', 'Argentina Sono Film S.A.C.I.')]
# [('comp', 'http://www.wikidata.org/entity/Q1538543'), ('name', 'State Committee for Cinematography')]
# [('comp', 'http://www.wikidata.org/entity/Q1550785'), ('name', 'UFA Serial Drama')]
# [('comp', 'http://www.wikidata.org/entity/Q17343522'), ('name', 'Robert Simonds Productions')]
# [('comp', 'http://www.wikidata.org/entity/Q17377479'), ('name', 'Edward Small Productions')]
# [('comp', 'http://www.wikidata.org/entity/Q2830819'), ('name', 'Films Albatros')]
# [('comp', 'http://www.wikidata.org/entity/Q2880386'), ('name', 'RTI Producciones')]
# [('comp', 'http://www.wikidata.org/entity/Q2945566'), ('name', 'Greek Film Centre')]
# [('comp', 'http://www.wikidata.org/entity/Q3046330'), ('name', 'Eagle-Lion Films')]
# [('comp', 'http://www.wikidata.org/entity/Q3298993'), ('name', 'Seven Arts Productions')]
# [('comp', 'http://www.wikidata.org/entity/Q3363246'), ('name', 'Paradis Films')]
# [('comp', 'http://www.wikidata.org/entity/Q3980774'), ('name', 'Tandem Productions')]
# [('comp', 'http://www.wikidata.org/entity/Q4341103'), ('name', 'Profit')]
# [('comp', 'http://www.wikidata.org/entity/Q4864505'), ('name', 'Barry Mendel Productions')]
# 100

# %%
#all tv or film prod companies that have stock exchange market
queryString = """
SELECT DISTINCT ?comp ?name 
WHERE {    
    VALUES ?prodComp {wd:Q10689397 wd:Q1762059} #either tv or film (resp.) prod comp
    # ?comp wdt:P31 ?prodComp;        
        sc:name ?name.
    FILTER EXISTS {?comp wdt:P414 ?o}
}

LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('comp', 'http://www.wikidata.org/entity/Q541569'), ('name', 'Orange Sky Golden Harvest')]
# [('comp', 'http://www.wikidata.org/entity/Q500088'), ('name', 'DreamWorks Animation')]
# [('comp', 'http://www.wikidata.org/entity/Q7414'), ('name', 'The Walt Disney Company')]
# [('comp', 'http://www.wikidata.org/entity/Q907311'), ('name', 'Netflix')]
# [('comp', 'http://www.wikidata.org/entity/Q2140077'), ('name', 'Tribune Media')]
# [('comp', 'http://www.wikidata.org/entity/Q5395348'), ('name', 'Eros International')]
# [('comp', 'http://www.wikidata.org/entity/Q1654103'), ('name', 'IMAX Corporation')]
# [('comp', 'http://www.wikidata.org/entity/Q604775'), ('name', '4Kids Entertainment')]
# [('comp', 'http://www.wikidata.org/entity/Q3299128'), ('name', 'Rainmaker Entertainment')]
# [('comp', 'http://www.wikidata.org/entity/Q1476080'), ('name', 'Private Media Group')]
# [('comp', 'http://www.wikidata.org/entity/Q56085408'), ('name', 'MD Pictures')]
# [('comp', 'http://www.wikidata.org/entity/Q825291'), ('name', 'Village Roadshow')]
# [('comp', 'http://www.wikidata.org/entity/Q3992245'), ('name', 'Tohokushinsha Film')]
# [('comp', 'http://www.wikidata.org/entity/Q11079561'), ('name', 'Alibaba Pictures')]
# 14

# %%
#names of companies per stock exchange market
queryString = """
SELECT ?name ?cName
WHERE {    
    VALUES ?prodComp {wd:Q10689397 wd:Q1762059} #either tv or film (resp.) prod comp
    # ?comp wdt:P31 ?prodComp;
        wdt:P414 ?sem; #sem is stock exchange market
        sc:name ?cName.
    # ?sem sc:name ?name.
}
GROUP BY ?sem ?name
ORDER BY ASC(?name)
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('name', 'Australian Securities Exchange'), ('cName', 'Village Roadshow')]
# [('name', 'Hong Kong Stock Exchange'), ('cName', 'Orange Sky Golden Harvest')]
# [('name', 'Hong Kong Stock Exchange'), ('cName', 'Alibaba Pictures')]
# [('name', 'Indonesia Stock Exchange'), ('cName', 'MD Pictures')]
# [('name', 'NASDAQ'), ('cName', 'Private Media Group')]
# [('name', 'NASDAQ'), ('cName', 'DreamWorks Animation')]
# [('name', 'NASDAQ'), ('cName', 'Netflix')]
# [('name', 'New York Stock Exchange'), ('cName', 'IMAX Corporation')]
# [('name', 'New York Stock Exchange'), ('cName', 'Tribune Media')]
# [('name', 'New York Stock Exchange'), ('cName', 'Eros International')]
# [('name', 'New York Stock Exchange'), ('cName', '4Kids Entertainment')]
# [('name', 'New York Stock Exchange'), ('cName', 'The Walt Disney Company')]
# [('name', 'Tokyo Stock Exchange'), ('cName', 'The Walt Disney Company')]
# [('name', 'Tokyo Stock Exchange'), ('cName', 'Tohokushinsha Film')]
# [('name', 'Toronto Stock Exchange'), ('cName', 'Rainmaker Entertainment')]
# 15

# %% [markdown]
# Final query for this task

# %%
#number of film/tv companies per stock exchange market 
#I included this final query because it was what i expected to be asked in the task, 
#the final query satisfying the task for all kind of companies is in the cell below
queryString = """
SELECT (?sem AS ?iri) ?name (COUNT(DISTINCT ?comp) AS ?Ncompanies)
WHERE {    
    VALUES ?prodComp {wd:Q10689397 wd:Q1762059} #either tv or film (resp.) prod comp
    # ?comp wdt:P31 ?prodComp;
        wdt:P414 ?sem. #sem is stock exchange market
    # ?sem sc:name ?name.
}
GROUP BY ?sem ?name
ORDER BY DESC(?Ncompanies) ASC(?name)
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('iri', 'http://www.wikidata.org/entity/Q13677'), ('name', 'New York Stock Exchange'), ('Ncompanies', '5')]
# [('iri', 'http://www.wikidata.org/entity/Q82059'), ('name', 'NASDAQ'), ('Ncompanies', '3')]
# [('iri', 'http://www.wikidata.org/entity/Q496672'), ('name', 'Hong Kong Stock Exchange'), ('Ncompanies', '2')]
# [('iri', 'http://www.wikidata.org/entity/Q217475'), ('name', 'Tokyo Stock Exchange'), ('Ncompanies', '2')]
# [('iri', 'http://www.wikidata.org/entity/Q732670'), ('name', 'Australian Securities Exchange'), ('Ncompanies', '1')]
# [('iri', 'http://www.wikidata.org/entity/Q1661737'), ('name', 'Indonesia Stock Exchange'), ('Ncompanies', '1')]
# [('iri', 'http://www.wikidata.org/entity/Q818723'), ('name', 'Toronto Stock Exchange'), ('Ncompanies', '1')]
# 7

# %%
#number of all kind of companies per stock exchange market
queryString = """
SELECT (?sem AS ?iri) ?name (COUNT(DISTINCT ?comp) AS ?Ncompanies)
WHERE {    
    
    # ?comp wdt:P414 ?sem. #sem is stock exchange market
    # ?sem sc:name ?name.
}
GROUP BY ?sem ?name
ORDER BY DESC(?Ncompanies) ASC(?name)
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('iri', 'http://www.wikidata.org/entity/Q13677'), ('name', 'New York Stock Exchange'), ('Ncompanies', '1832')]
# [('iri', 'http://www.wikidata.org/entity/Q496672'), ('name', 'Hong Kong Stock Exchange'), ('Ncompanies', '1799')]
# [('iri', 'http://www.wikidata.org/entity/Q82059'), ('name', 'NASDAQ'), ('Ncompanies', '1755')]
# [('iri', 'http://www.wikidata.org/entity/Q1661737'), ('name', 'Indonesia Stock Exchange'), ('Ncompanies', '697')]
# [('iri', 'http://www.wikidata.org/entity/Q171240'), ('name', 'London Stock Exchange'), ('Ncompanies', '604')]
# [('iri', 'http://www.wikidata.org/entity/Q517750'), ('name', 'Shenzhen Stock Exchange'), ('Ncompanies', '493')]
# [('iri', 'http://www.wikidata.org/entity/Q217475'), ('name', 'Tokyo Stock Exchange'), ('Ncompanies', '460')]
# [('iri', 'http://www.wikidata.org/entity/Q495364'), ('name', 'Korea Stock Exchange'), ('Ncompanies', '417')]
# [('iri', 'http://www.wikidata.org/entity/Q818723'), ('name', 'Toronto Stock Exchange'), ('Ncompanies', '394')]
# [('iri', 'http://www.wikidata.org/entity/Q1930860'), ('name', 'OTC Markets Group'), ('Ncompanies', '364')]
# [('iri', 'http://www.wikidata.org/entity/Q739514'), ('name', 'Shanghai Stock Exchange'), ('Ncompanies', '356')]
# [('iri', 'http://www.wikidata.org/entity/Q6529599'), ('name', 'Nepal Stock Exchange'), ('Ncompanies', '346')]
# [('iri', 'http://www.wikidata.org/entity/Q59551'), ('name', 'Warsaw Stock Exchange'), ('Ncompanies', '257')]
# [('iri', 'http://www.wikidata.org/entity/Q2006583'), ('name', 'Tadawul'), ('Ncompanies', '180')]
# [('iri', 'http://www.wikidata.org/entity/Q796297'), ('name', 'B3'), ('Ncompanies', '156')]
# [('iri', 'http://www.wikidata.org/entity/Q909158'), ('name', 'Oslo Stock Exchange'), ('Ncompanies', '154')]
# [('iri', 'http://www.wikidata.org/entity/Q732670'), ('name', 'Australian Securities Exchange'), ('Ncompanies', '146')]
# [('iri', 'http://www.wikidata.org/entity/Q638740'), ('name', 'National Stock Exchange of India'), ('Ncompanies', '141')]
# [('iri', 'http://www.wikidata.org/entity/Q2632892'), ('name', 'Moscow Exchange'), ('Ncompanies', '128')]
# [('iri', 'http://www.wikidata.org/entity/Q1019983'), ('name', 'Nasdaq Copenhagen'), ('Ncompanies', '99')]
# [('iri', 'http://www.wikidata.org/entity/Q151139'), ('name', 'Frankfurt Stock Exchange'), ('Ncompanies', '97')]
# [('iri', 'http://www.wikidata.org/entity/Q842108'), ('name', 'Euronext'), ('Ncompanies', '91')]
# [('iri', 'http://www.wikidata.org/entity/Q548621'), ('name', 'Taiwan Stock Exchange'), ('Ncompanies', '84')]
# [('iri', 'http://www.wikidata.org/entity/Q495372'), ('name', 'Korea Exchange'), ('Ncompanies', '61')]
# [('iri', 'http://www.wikidata.org/entity/Q581755'), ('name', 'Nasdaq Helsinki'), ('Ncompanies', '58')]
# [('iri', 'http://www.wikidata.org/entity/Q1507974'), ('name', 'Tel Aviv Stock Exchange'), ('Ncompanies', '55')]
# [('iri', 'http://www.wikidata.org/entity/Q1805567'), ('name', 'Tehran Stock Exchange'), ('Ncompanies', '50')]
# [('iri', 'http://www.wikidata.org/entity/Q1019992'), ('name', 'Nasdaq Stockholm'), ('Ncompanies', '49')]
# [('iri', 'http://www.wikidata.org/entity/Q1188840'), ('name', 'Nagoya Stock Exchange'), ('Ncompanies', '41')]
# [('iri', 'http://www.wikidata.org/entity/Q2385849'), ('name', 'Euronext Paris'), ('Ncompanies', '40')]
# [('iri', 'http://www.wikidata.org/entity/Q661834'), ('name', 'SIX Swiss Exchange'), ('Ncompanies', '40')]
# [('iri', 'http://www.wikidata.org/entity/Q1752646'), ('name', 'Prague Stock Exchange'), ('Ncompanies', '39')]
# [('iri', 'http://www.wikidata.org/entity/Q891561'), ('name', 'Santiago Stock Exchange'), ('Ncompanies', '37')]
# [('iri', 'http://www.wikidata.org/entity/Q638398'), ('name', 'Bombay Stock Exchange'), ('Ncompanies', '35')]
# [('iri', 'http://www.wikidata.org/entity/Q936563'), ('name', 'Italian Bourse'), ('Ncompanies', '34')]
# [('iri', 'http://www.wikidata.org/entity/Q617426'), ('name', 'Bolsa de Madrid'), ('Ncompanies', '32')]
# [('iri', 'http://www.wikidata.org/entity/Q627019'), ('name', 'New Zealand Exchange'), ('Ncompanies', '27')]
# [('iri', 'http://www.wikidata.org/entity/Q627514'), ('name', 'JSE Limited'), ('Ncompanies', '25')]
# [('iri', 'http://www.wikidata.org/entity/Q11093491'), ('name', 'Sapporo Securities Exchange'), ('Ncompanies', '23')]
# [('iri', 'http://www.wikidata.org/entity/Q5507703'), ('name', 'Fukuoka Stock Exchange'), ('Ncompanies', '20')]
# [('iri', 'http://www.wikidata.org/entity/Q491503'), ('name', 'KOSDAQ'), ('Ncompanies', '16')]
# [('iri', 'http://www.wikidata.org/entity/Q11340130'), ('name', 'Mothers'), ('Ncompanies', '16')]
# [('iri', 'http://www.wikidata.org/entity/Q698535'), ('name', 'Wiener Börse'), ('Ncompanies', '16')]
# [('iri', 'http://www.wikidata.org/entity/Q1330208'), ('name', 'Stock Exchange of Thailand'), ('Ncompanies', '14')]
# [('iri', 'http://www.wikidata.org/entity/Q755341'), ('name', 'Athens Exchange'), ('Ncompanies', '13')]
# [('iri', 'http://www.wikidata.org/entity/Q1683760'), ('name', 'JASDAQ Securities Exchange'), ('Ncompanies', '13')]
# [('iri', 'http://www.wikidata.org/entity/Q1344438'), ('name', 'Russian Trading System'), ('Ncompanies', '13')]
# [('iri', 'http://www.wikidata.org/entity/Q1515558'), ('name', 'Singapore Exchange'), ('Ncompanies', '12')]
# [('iri', 'http://www.wikidata.org/entity/Q140388'), ('name', 'Zagreb Stock Exchange'), ('Ncompanies', '12')]
# [('iri', 'http://www.wikidata.org/entity/Q478720'), ('name', 'Euronext Amsterdam'), ('Ncompanies', '11')]
# [('iri', 'http://www.wikidata.org/entity/Q1132158'), ('name', 'OMX AB'), ('Ncompanies', '11')]
# [('iri', 'http://www.wikidata.org/entity/Q1984912'), ('name', 'PFTS Ukraine Stock Exchange'), ('Ncompanies', '11')]
# [('iri', 'http://www.wikidata.org/entity/Q851259'), ('name', 'Budapest Stock Exchange'), ('Ncompanies', '9')]
# [('iri', 'http://www.wikidata.org/entity/Q144458'), ('name', 'Euronext Dublin'), ('Ncompanies', '9')]
# [('iri', 'http://www.wikidata.org/entity/Q891559'), ('name', 'Mexican Stock Exchange'), ('Ncompanies', '9')]
# [('iri', 'http://www.wikidata.org/entity/Q11249728'), ('name', 'Tokyo Pro Market'), ('Ncompanies', '9')]
# [('iri', 'http://www.wikidata.org/entity/Q438511'), ('name', 'Alternative Investment Market'), ('Ncompanies', '8')]
# [('iri', 'http://www.wikidata.org/entity/Q51403327'), ('name', 'Binance'), ('Ncompanies', '8')]
# [('iri', 'http://www.wikidata.org/entity/Q1734773'), ('name', 'Kazakhstan Stock Exchange'), ('Ncompanies', '8')]
# [('iri', 'http://www.wikidata.org/entity/Q846626'), ('name', 'NYSE American'), ('Ncompanies', '8')]
# [('iri', 'http://www.wikidata.org/entity/Q3642744'), ('name', 'Stock Exchange in Milano'), ('Ncompanies', '8')]
# [('iri', 'http://www.wikidata.org/entity/Q5598539'), ('name', 'Taipei Exchange'), ('Ncompanies', '8')]
# [('iri', 'http://www.wikidata.org/entity/Q43335'), ('name', 'Bursa Malaysia'), ('Ncompanies', '7')]
# [('iri', 'http://www.wikidata.org/entity/Q2415561'), ('name', 'Euronext Lisbon'), ('Ncompanies', '7')]
# [('iri', 'http://www.wikidata.org/entity/Q74662'), ('name', 'Fundsquare Market Infrastructure'), ('Ncompanies', '7')]
# [('iri', 'http://www.wikidata.org/entity/Q1320224'), ('name', 'Osaka Exchange'), ('Ncompanies', '7')]
# [('iri', 'http://www.wikidata.org/entity/Q12048417'), ('name', 'RM-SYSTÉM, česká burza cenných papírů'), ('Ncompanies', '7')]
# [('iri', 'http://www.wikidata.org/entity/Q1407995'), ('name', 'Borsa Istanbul'), ('Ncompanies', '6')]
# [('iri', 'http://www.wikidata.org/entity/Q891560'), ('name', 'Buenos Aires Stock Exchange'), ('Ncompanies', '6')]
# [('iri', 'http://www.wikidata.org/entity/Q1146518'), ('name', 'Euronext Brussels'), ('Ncompanies', '6')]
# [('iri', 'http://www.wikidata.org/entity/Q819468'), ('name', 'Xetra'), ('Ncompanies', '6')]
# [('iri', 'http://www.wikidata.org/entity/Q20992132'), ('name', 'Yangon Stock Exchange'), ('Ncompanies', '6')]
# [('iri', 'http://www.wikidata.org/entity/Q16972754'), ('name', 'Coinbase'), ('Ncompanies', '5')]
# [('iri', 'http://www.wikidata.org/entity/Q10855618'), ('name', 'NewConnect'), ('Ncompanies', '5')]
# [('iri', 'http://www.wikidata.org/entity/Q1526647'), ('name', 'Philippine Stock Exchange'), ('Ncompanies', '5')]
# [('iri', 'http://www.wikidata.org/entity/Q29647473'), ('name', 'Bitfinex'), ('Ncompanies', '4')]
# [('iri', 'http://www.wikidata.org/entity/Q1974408'), ('name', 'Dhaka Stock Exchange'), ('Ncompanies', '4')]
# [('iri', 'http://www.wikidata.org/entity/Q2382352'), ('name', 'Bermuda Stock Exchange'), ('Ncompanies', '3')]
# [('iri', 'http://www.wikidata.org/entity/Q4202960'), ('name', 'Bolsa de Valores de Barcelona'), ('Ncompanies', '3')]
# [('iri', 'http://www.wikidata.org/entity/Q74603'), ('name', 'Bratislava Stock Exchange'), ('Ncompanies', '3')]
# [('iri', 'http://www.wikidata.org/entity/Q1003968'), ('name', 'Bulgarian Stock Exchange'), ('Ncompanies', '3')]
# [('iri', 'http://www.wikidata.org/entity/Q2633007'), ('name', 'Chicago Stock Exchange'), ('Ncompanies', '3')]
# [('iri', 'http://www.wikidata.org/entity/Q157852'), ('name', 'Deutsche Börse'), ('Ncompanies', '3')]
# [('iri', 'http://www.wikidata.org/entity/Q1433248'), ('name', 'Nasdaq Tallinn'), ('Ncompanies', '3')]
# [('iri', 'http://www.wikidata.org/entity/Q1391676'), ('name', 'OTC Bulletin Board'), ('Ncompanies', '3')]
# [('iri', 'http://www.wikidata.org/entity/Q22907578'), ('name', 'Pakistan Stock Exchange'), ('Ncompanies', '3')]
# [('iri', 'http://www.wikidata.org/entity/Q178513'), ('name', 'Paris Bourse'), ('Ncompanies', '3')]
# [('iri', 'http://www.wikidata.org/entity/Q11240145'), ('name', 'Q-Board'), ('Ncompanies', '3')]
# [('iri', 'http://www.wikidata.org/entity/Q93360933'), ('name', 'Spotlight Stock Market'), ('Ncompanies', '3')]
# [('iri', 'http://www.wikidata.org/entity/Q2387368'), ('name', 'zero two desnuda'), ('Ncompanies', '3')]
# [('iri', 'http://www.wikidata.org/entity/Q683787'), ('name', 'Armenia Securities Exchange'), ('Ncompanies', '2')]
# [('iri', 'http://www.wikidata.org/entity/Q12721279'), ('name', 'Australian Stock Exchange'), ('Ncompanies', '2')]
# [('iri', 'http://www.wikidata.org/entity/Q550050'), ('name', 'Belgrade Stock Exchange'), ('Ncompanies', '2')]
# [('iri', 'http://www.wikidata.org/entity/Q609159'), ('name', 'Bolsas y Mercados Españoles'), ('Ncompanies', '2')]
# [('iri', 'http://www.wikidata.org/entity/Q1003245'), ('name', 'Bucharest Stock Exchange'), ('Ncompanies', '2')]
# [('iri', 'http://www.wikidata.org/entity/Q3349831'), ('name', 'Chittagong Stock Exchange'), ('Ncompanies', '2')]
# [('iri', 'http://www.wikidata.org/entity/Q2718247'), ('name', 'Euronext Growth'), ('Ncompanies', '2')]
# [('iri', 'http://www.wikidata.org/entity/Q97574837'), ('name', 'GDAX'), ('Ncompanies', '2')]
# [('iri', 'http://www.wikidata.org/entity/Q19892740'), ('name', 'Huobi'), ('Ncompanies', '2')]
# [('iri', 'http://www.wikidata.org/entity/Q1977283'), ('name', 'Karachi Stock Exchange'), ('Ncompanies', '2')]
# 100

# %% [markdown]
# ## Task 8
# Identify the BGP for Academy Award

# %%
# Lion King awards
queryString = """
SELECT DISTINCT ?obj ?name
WHERE {
   # bind something
   wd:Q36479 wdt:P166 ?obj .
   # get the label
   # ?obj sc:name ?name.
}
ORDER BY ASC(?name)
LIMIT 1000
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('obj', 'http://www.wikidata.org/entity/Q488651'), ('name', 'Academy Award for Best Original Score')]
# [('obj', 'http://www.wikidata.org/entity/Q823422'), ('name', 'National Film Registry')]
# 2

# %%
# AA for Best original score instance of
queryString = """
SELECT DISTINCT ?obj ?name
WHERE {
   # bind something
   wd:Q488651 wdt:P31 ?obj .
   # get the label
   # ?obj sc:name ?name.
}
ORDER BY ASC(?name)
LIMIT 1000
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('obj', 'http://www.wikidata.org/entity/Q19020'), ('name', 'Academy Awards')]
# [('obj', 'http://www.wikidata.org/entity/Q96474685'), ('name', 'award for best original music')]
# 2

# %%
# AAs all props
queryString = """
SELECT DISTINCT ?p ?pName ?name
WHERE {
   # bind something
   wd:Q19020 ?p ?obj .
   # get the label
   # ?p sc:name ?pName.
   # ?obj sc:name ?name.
}
ORDER BY ASC(?name)
LIMIT 1000
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P1889'), ('pName', 'different from'), ('name', 'Academy Award')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('name', 'Academy Award for Best Actor')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('name', 'Academy Award for Best Actress')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('name', 'Academy Award for Best Animated Feature')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('name', 'Academy Award for Best Cinematography')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('name', 'Academy Award for Best Costume Design')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('name', 'Academy Award for Best Director')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('name', 'Academy Award for Best Director (Comedy picture)')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('name', 'Academy Award for Best Documentary Feature')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('name', 'Academy Award for Best Foreign Language Film')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('name', 'Academy Award for Best Original Dramatic Score')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('name', 'Academy Award for Best Original Score')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('name', 'Academy Award for Best Original Song')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('name', 'Academy Award for Best Picture')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('name', 'Academy Award for Best Supporting Actor')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('name', 'Academy Award for Best Supporting Actress')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('name', 'Academy Award for Best Writing, Adapted Screenplay')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('name', 'Academy Award for Best Writing, Original Screenplay')]
# [('p', 'http://www.wikidata.org/prop/direct/P1889'), ('pName', 'different from'), ('name', 'Academy Awards ceremony')]
# [('p', 'http://www.wikidata.org/prop/direct/P1027'), ('pName', 'conferred by'), ('name', 'Academy of Motion Picture Arts and Sciences')]
# [('p', 'http://www.wikidata.org/prop/direct/P2517'), ('pName', 'category for recipients of this award'), ('name', 'Category:Academy Award winners')]
# [('p', 'http://www.wikidata.org/prop/direct/P910'), ('pName', "topic's main category"), ('name', 'Category:Academy Awards')]
# [('p', 'http://www.wikidata.org/prop/direct/P1343'), ('pName', 'described by source'), ('name', 'Disney A to Z')]
# [('p', 'http://www.wikidata.org/prop/direct/P4622'), ('pName', 'trophy awarded'), ('name', 'Oscar statuette')]
# [('p', 'http://www.wikidata.org/prop/direct/P1424'), ('pName', "topic's main template"), ('name', 'Template:Academy Awards')]
# [('p', 'http://www.wikidata.org/prop/direct/P1424'), ('pName', "topic's main template"), ('name', 'Template:Infobox Academy Awards')]
# [('p', 'http://www.wikidata.org/prop/direct/P17'), ('pName', 'country'), ('name', 'United States of America')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('name', 'film award')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('name', 'group of awards')]
# [('p', 'http://www.wikidata.org/prop/direct/P1889'), ('pName', 'different from'), ('name', 'Óscar')]
# 30

# %%
# AAs different from
queryString = """
SELECT DISTINCT ?obj ?name
WHERE {
   # bind something
   wd:Q19020 wdt:P1889 ?obj .
   # get the label
   # ?obj sc:name ?name.
}
ORDER BY ASC(?name)
LIMIT 1000
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('obj', 'http://www.wikidata.org/entity/Q4671334'), ('name', 'Academy Award')]
# [('obj', 'http://www.wikidata.org/entity/Q16913666'), ('name', 'Academy Awards ceremony')]
# [('obj', 'http://www.wikidata.org/entity/Q21475960'), ('name', 'Óscar')]
# 3

# %% [markdown]
# Final query for this task

# %%
# BGP for Academy Award
queryString = """
SELECT *
WHERE {
   BIND(wd:Q4671334 AS ?iri)
   # ?iri sc:name ?name.
}
LIMIT 10
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('iri', 'http://www.wikidata.org/entity/Q4671334'), ('name', 'Academy Award')]
# 1

# %% [markdown]
# ## Task 9
# Find the companies (among television and film production companies) that won at least 5 Academy Awards for Best Actress for the movies they produced (the result set must be a list of triples company IRI, label and #awards).

# %%
# AAs all parts
queryString = """
SELECT DISTINCT ?obj ?name
WHERE {
   # bind something
   wd:Q19020 wdt:P527 ?obj .
   # get the label
   # ?obj sc:name ?name.
}
ORDER BY ASC(?name)
LIMIT 1000
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('obj', 'http://www.wikidata.org/entity/Q103916'), ('name', 'Academy Award for Best Actor')]
# [('obj', 'http://www.wikidata.org/entity/Q103618'), ('name', 'Academy Award for Best Actress')]
# [('obj', 'http://www.wikidata.org/entity/Q106800'), ('name', 'Academy Award for Best Animated Feature')]
# [('obj', 'http://www.wikidata.org/entity/Q131520'), ('name', 'Academy Award for Best Cinematography')]
# [('obj', 'http://www.wikidata.org/entity/Q277536'), ('name', 'Academy Award for Best Costume Design')]
# [('obj', 'http://www.wikidata.org/entity/Q103360'), ('name', 'Academy Award for Best Director')]
# [('obj', 'http://www.wikidata.org/entity/Q3451157'), ('name', 'Academy Award for Best Director (Comedy picture)')]
# [('obj', 'http://www.wikidata.org/entity/Q111332'), ('name', 'Academy Award for Best Documentary Feature')]
# [('obj', 'http://www.wikidata.org/entity/Q105304'), ('name', 'Academy Award for Best Foreign Language Film')]
# [('obj', 'http://www.wikidata.org/entity/Q22235329'), ('name', 'Academy Award for Best Original Dramatic Score')]
# [('obj', 'http://www.wikidata.org/entity/Q488651'), ('name', 'Academy Award for Best Original Score')]
# [('obj', 'http://www.wikidata.org/entity/Q112243'), ('name', 'Academy Award for Best Original Song')]
# [('obj', 'http://www.wikidata.org/entity/Q102427'), ('name', 'Academy Award for Best Picture')]
# [('obj', 'http://www.wikidata.org/entity/Q106291'), ('name', 'Academy Award for Best Supporting Actor')]
# [('obj', 'http://www.wikidata.org/entity/Q106301'), ('name', 'Academy Award for Best Supporting Actress')]
# [('obj', 'http://www.wikidata.org/entity/Q107258'), ('name', 'Academy Award for Best Writing, Adapted Screenplay')]
# [('obj', 'http://www.wikidata.org/entity/Q41417'), ('name', 'Academy Award for Best Writing, Original Screenplay')]
# 17

# %%
#prova finale
queryString = """
SELECT DISTINCT (?comp AS ?iri) ?name (COUNT(?film) AS ?Nawards)
WHERE {
    VALUES ?prodComp {wd:Q10689397 wd:Q1762059} #either tv or film (resp.) prod comp
    # ?comp wdt:P31 ?prodComp;
        sc:name ?name.
    # ?film wdt:P272 ?comp;                       #film produced by comp
        wdt:P166 wd:Q103618.                    #     won best actress

}
GROUP BY ?comp ?name
HAVING(COUNT(?film) > 4)
ORDER BY DESC(?Nawards)                        #VALUES PUO'PRENDERE DOPPI SE VALE PER ENTRAMBI 
LIMIT 100                                      #(sia tv che film in questo caso)

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('iri', 'http://www.wikidata.org/entity/Q434841'), ('name', '20th Century Studios'), ('Nawards', '14')]
# [('iri', 'http://www.wikidata.org/entity/Q179200'), ('name', 'Metro-Goldwyn-Mayer'), ('Nawards', '11')]
# [('iri', 'http://www.wikidata.org/entity/Q159846'), ('name', 'Paramount Pictures'), ('Nawards', '11')]
# [('iri', 'http://www.wikidata.org/entity/Q126399'), ('name', 'Warner Bros.'), ('Nawards', '9')]
# 4

# %%
#all best actress oscar films of 20th Cent.
queryString = """
SELECT ?name 
WHERE {
    # ?film wdt:P272 wd:Q434841;                       #film produced by 20th Cent
        wdt:P166 wd:Q103618;                         #won best actress
        sc:name ?name.                    
}

ORDER BY DESC(?Nawards)
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('name', 'Seventh Heaven')]
# [('name', 'Walk the Line')]
# [('name', 'Sunrise: A Song of Two Humans')]
# [('name', 'The Three Faces of Eve')]
# [('name', 'Anastasia')]
# [('name', 'The Prime of Miss Jean Brodie')]
# [('name', 'The Song of Bernadette')]
# 7

# %%
#prova finale 2
queryString = """
SELECT DISTINCT (?comp AS ?iri) ?name (COUNT(DISTINCT ?film) AS ?Nawards)
WHERE {
    VALUES ?prodComp {wd:Q10689397 wd:Q1762059} #either tv or film (resp.) prod comp
    # ?comp wdt:P31 ?prodComp;
        sc:name ?name.
    # ?film wdt:P272 ?comp;                       #film produced by comp
        wdt:P166 wd:Q103618.                    #     won best actress

}
GROUP BY ?comp ?name
HAVING(COUNT(DISTINCT ?film) > 4)
ORDER BY DESC(?Nawards) ASC(?name)
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('iri', 'http://www.wikidata.org/entity/Q179200'), ('name', 'Metro-Goldwyn-Mayer'), ('Nawards', '11')]
# [('iri', 'http://www.wikidata.org/entity/Q159846'), ('name', 'Paramount Pictures'), ('Nawards', '11')]
# [('iri', 'http://www.wikidata.org/entity/Q126399'), ('name', 'Warner Bros.'), ('Nawards', '9')]
# [('iri', 'http://www.wikidata.org/entity/Q434841'), ('name', '20th Century Studios'), ('Nawards', '7')]
# 4

# %% [markdown]
# Final query for this task

# %%
#number of best actress award winning films produced by each company
queryString = """
SELECT DISTINCT (?comp AS ?iri) ?name (COUNT(DISTINCT ?film) AS ?Nawards)
WHERE {
    VALUES ?prodComp {wd:Q10689397 wd:Q1762059} #either tv or film (resp.) prod comp
    # ?comp wdt:P31 ?prodComp;
        sc:name ?name.
    # ?film wdt:P272 ?comp;                       #film produced by comp
        wdt:P166 wd:Q103618.                    #     won best actress

}
GROUP BY ?comp ?name
HAVING(COUNT(DISTINCT ?film) > 4)
ORDER BY DESC(?Nawards) ASC(?name)
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('iri', 'http://www.wikidata.org/entity/Q179200'), ('name', 'Metro-Goldwyn-Mayer'), ('Nawards', '11')]
# [('iri', 'http://www.wikidata.org/entity/Q159846'), ('name', 'Paramount Pictures'), ('Nawards', '11')]
# [('iri', 'http://www.wikidata.org/entity/Q126399'), ('name', 'Warner Bros.'), ('Nawards', '9')]
# [('iri', 'http://www.wikidata.org/entity/Q434841'), ('name', '20th Century Studios'), ('Nawards', '7')]
# 4

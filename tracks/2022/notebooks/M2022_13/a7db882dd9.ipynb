# %% [markdown]
# # General instructions
#
# The goal of the project is to materialize a set of **exploratory workloads** over a real-world, large-scale,  open-domain KG: [WikiData](https://www.wikidata.org/wiki/Wikidata:Main_Page)
#
# An exploratory workload  is composed by a set of queries, where each query is related to the information obtained previously.
#
# An exploratory workload starts with a usually vague, open ended question, and does not assume the person issuing the workload has a clear understanding of the data contained in the target database or its structure.
#
# Remeber that:
#
# 1. All the queries must run in the python notebook
# 2. You can use classes and properties only if you find them via a SPARQL query that must be present in the notebook
# 3. You do not delete useless queries. Keep everything that is synthatically valid
#
# ```
# ?p <http://schema.org/name> ?name .
# ```
#
#     is the BGP returning a human-readable name of a property or a class in Wikidata.

# %%
## SETUP used later

from SPARQLWrapper import SPARQLWrapper, JSON


prefixString = """
##-a7db882dd9-##
PREFIX wd: <http://www.wikidata.org/entity/> 
PREFIX wdt: <http://www.wikidata.org/prop/direct/> 
PREFIX sc: <http://schema.org/>
"""

# select and construct queries
def run_query(queryString,verbose = True):
    to_run = prefixString + "\n" + queryString

    sparql = SPARQLWrapper("http://a256-gc1-03.srv.aau.dk:5820/sparql")
    sparql.setTimeout(300)
    sparql.setReturnFormat(JSON)
    sparql.setQuery(to_run)

    try :
        results = sparql.query()
        json_results = results.convert()
        if len(json_results['results']['bindings'])==0:
            print("Empty")
            return []
        array = []
        for bindings in json_results['results']['bindings']:
            app =  [ (var, value['value'])  for var, value in bindings.items() ] 
            if verbose:
                print( app)
            array.append(app)
        if verbose:
            print(len(array))
        return array

    except Exception as e :
        print("The operation failed", e)
    
# ASk queries
def run_ask_query(queryString):
    to_run = prefixString + "\n" + queryString

    sparql = SPARQLWrapper("http://a256-gc1-03.srv.aau.dk:5820/sparql")
    sparql.setTimeout(300)
    sparql.setReturnFormat(JSON)
    sparql.setQuery(to_run)

    try :
        return sparql.query().convert()

    except Exception as e :
        print("The operation failed", e)

# %% [markdown]
# # History Workflow Series ("Literary Movements and Divine Comedy explorative search")
#
# Consider the following exploratory information need:
#
# > investigate the literary movements and the poets. In particular, compare some italian poets in terms of place of birth, number of literary works and education.

# %% [markdown]
# ## Useful URIs for the current workflow
# The following are given:
#
# | IRI           | Description   | Role      |
# | -----------   | -----------   |-----------|
# | `wdt:P1647`   | subproperty   | predicate |
# | `wdt:P31`     | instance of   | predicate |
# | `wdt:P106`    | occupation    | predicate |
# | `wdt:P279`    | subclass      | predicate |
# | `wdt:P27`     | nationality   | predicate |
# | `wdt:P3342`     | Significant person       | predicate |
# | `wd:Q5`| Human       | node |
# | `wd:Q40185`| The Divine Comedy  | node |

# %% [markdown]
# Also consider
#
# ```
# wd:Q40185 ?p ?obj .
# ```
#
# is the BGP to retrieve all **properties of The Divine Comedy**
#
# Please consider that when you return a resource, you should return the IRI and the label of the resource. In particular, when the task require you to identify a BGP the result set must always be a list of couples IRI - label.
#
# The workload should:
#
# 1. Who wrote The Divine Comedy? (return the IRI and the label of the author)
#
# 2. Identify the BGP for poet
#
# 3. Identify the BGP for literary movement
#
# 4. Return the poets born in the same place of the author of The Divine Comedy who are born between 1300 and 1500 (1300 and 1500 included) (the result set must be a list of couples poets IRI and label).
#
# 5. Identify the BGP for literary work
#
# 6. Compare the author of The Divine Comedy with Giovanni Boccaccio. Return for these poets the number of literary work they wrote (the result set must be two triples -one for each author- author IRI, label and #literary work).
#
# 7. Consider italian poets, their place of birth (the city) and their university education. Return for each city the number of poets who born there and who was educated there (the result set must be a list of triples city IRI, label and #poets).
#
# 8. Return the italian poets who won the Nobel Prize in Literature (the result set must be poet IRI and label).

# %% [markdown]
# ## Task 1
# Who wrote The Divine Comedy? (return the IRI and the label of the author)

# %%
# query example
queryString = """
SELECT DISTINCT ?p ?name
WHERE {
   # bind something
   wd:Q40185 ?p ?obj .
   # get the label
   # ?p sc:name ?name.
}
LIMIT 50
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P2551'), ('name', 'used metre')]
# [('p', 'http://www.wikidata.org/prop/direct/P1273'), ('name', 'CANTIC ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1296'), ('name', 'Gran Enciclopèdia Catalana ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1343'), ('name', 'described by source')]
# [('p', 'http://www.wikidata.org/prop/direct/P136'), ('name', 'genre')]
# [('p', 'http://www.wikidata.org/prop/direct/P1417'), ('name', 'Encyclopædia Britannica Online ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P18'), ('name', 'image')]
# [('p', 'http://www.wikidata.org/prop/direct/P1889'), ('name', 'different from')]
# [('p', 'http://www.wikidata.org/prop/direct/P214'), ('name', 'VIAF ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P227'), ('name', 'GND ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P244'), ('name', 'Library of Congress authority ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P268'), ('name', 'Bibliothèque nationale de France ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P269'), ('name', 'IdRef ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('name', 'instance of')]
# [('p', 'http://www.wikidata.org/prop/direct/P3219'), ('name', 'Encyclopædia Universalis ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3417'), ('name', 'Quora topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P373'), ('name', 'Commons category')]
# [('p', 'http://www.wikidata.org/prop/direct/P407'), ('name', 'language of work or name')]
# [('p', 'http://www.wikidata.org/prop/direct/P409'), ('name', 'Libraries Australia ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P435'), ('name', 'MusicBrainz work ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P50'), ('name', 'author')]
# [('p', 'http://www.wikidata.org/prop/direct/P5063'), ('name', 'Interlingual Index ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('name', 'has part')]
# [('p', 'http://www.wikidata.org/prop/direct/P571'), ('name', 'inception')]
# [('p', 'http://www.wikidata.org/prop/direct/P5986'), ('name', 'Getty Iconography Authority ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P646'), ('name', 'Freebase ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P674'), ('name', 'characters')]
# [('p', 'http://www.wikidata.org/prop/direct/P6839'), ('name', 'TV Tropes identifier')]
# [('p', 'http://www.wikidata.org/prop/direct/P691'), ('name', 'NKCR AUT ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7314'), ('name', 'TDV İslam Ansiklopedisi ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P747'), ('name', 'has edition or translation')]
# [('p', 'http://www.wikidata.org/prop/direct/P8189'), ('name', 'National Library of Israel J9U ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8248'), ('name', 'Colon Classification')]
# [('p', 'http://www.wikidata.org/prop/direct/P8408'), ('name', 'KBpedia ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8885'), ('name', 'Namuwiki ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P906'), ('name', 'SELIBR ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P910'), ('name', "topic's main category")]
# [('p', 'http://www.wikidata.org/prop/direct/P9223'), ('name', 'Provenio UUID')]
# [('p', 'http://www.wikidata.org/prop/direct/P9322'), ('name', 'SVKKL authority ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P949'), ('name', 'National Library of Israel ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P950'), ('name', 'Biblioteca Nacional de España ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1274'), ('name', 'ISFDB title ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6175'), ('name', 'Bitraga work ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8359'), ('name', 'Dewey Decimal Classification (works and editions)')]
# [('p', 'http://www.wikidata.org/prop/direct/P2034'), ('name', 'Project Gutenberg ebook ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3976'), ('name', 'BVMC work ID')]
# 46

# %% [markdown]
# Final query for this task

# %%
# write your final query
queryString = """
SELECT DISTINCT ?auteur ?name
WHERE {
   # bind something
   wd:Q40185 wdt:P50 ?auteur .
   # get the label
   # ?auteur sc:name ?name.
}
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('auteur', 'http://www.wikidata.org/entity/Q1067'), ('name', 'Dante Alighieri')]
# 1

# %% [markdown]
# ## Task 2
# Identify the BGP for poet

# %%
# write your queries

# %% [markdown]
# Final query for this task

# %%
# write your final query
# we're retrieveing all the occupations of Dante
queryString = """
SELECT DISTINCT ?o ?name
WHERE {
   # bind something
   wd:Q1067 wdt:P106 ?o . 
   # get the label
   # ?o sc:name ?name.
}
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('o', 'http://www.wikidata.org/entity/Q12144794'), ('name', 'prosaist')]
# [('o', 'http://www.wikidata.org/entity/Q15994177'), ('name', 'political theorist')]
# [('o', 'http://www.wikidata.org/entity/Q36180'), ('name', 'writer')]
# [('o', 'http://www.wikidata.org/entity/Q482980'), ('name', 'author')]
# [('o', 'http://www.wikidata.org/entity/Q4964182'), ('name', 'philosopher')]
# [('o', 'http://www.wikidata.org/entity/Q49757'), ('name', 'poet')]
# [('o', 'http://www.wikidata.org/entity/Q822146'), ('name', 'lyricist')]
# [('o', 'http://www.wikidata.org/entity/Q82955'), ('name', 'politician')]
# [('o', 'http://www.wikidata.org/entity/Q58968'), ('name', 'intellectual')]
# 9

# %% [markdown]
# ## Task 3
# Identify the BGP for literary movement

# %%
# write your queries
# we're retrieving all the properties and object of poet
queryString = """
SELECT DISTINCT ?p ?name 
WHERE {
   # bind something
    wd:Q49757 ?p ?obj .
   # get the label
   # ?p sc:name ?name .
}
LIMIT 50
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P1014'), ('name', 'Art & Architecture Thesaurus ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1296'), ('name', 'Gran Enciclopèdia Catalana ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1343'), ('name', 'described by source')]
# [('p', 'http://www.wikidata.org/prop/direct/P1709'), ('name', 'equivalent class')]
# [('p', 'http://www.wikidata.org/prop/direct/P1889'), ('name', 'different from')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('name', 'properties for this type')]
# [('p', 'http://www.wikidata.org/prop/direct/P227'), ('name', 'GND ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P244'), ('name', 'Library of Congress authority ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2581'), ('name', 'BabelNet ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P268'), ('name', 'Bibliothèque nationale de France ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('name', 'subclass of')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('name', 'instance of')]
# [('p', 'http://www.wikidata.org/prop/direct/P3417'), ('name', 'Quora topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P349'), ('name', 'National Diet Library ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3553'), ('name', 'Zhihu topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P373'), ('name', 'Commons category')]
# [('p', 'http://www.wikidata.org/prop/direct/P3916'), ('name', 'UNESCO Thesaurus ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P4212'), ('name', 'PACTOLS thesaurus ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P425'), ('name', 'field of this occupation')]
# [('p', 'http://www.wikidata.org/prop/direct/P460'), ('name', 'said to be the same as')]
# [('p', 'http://www.wikidata.org/prop/direct/P508'), ('name', 'BNCF Thesaurus ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5160'), ('name', 'Thesaurus for Graphic Materials ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6186'), ('name', 'category for eponymous categories')]
# [('p', 'http://www.wikidata.org/prop/direct/P6262'), ('name', 'Fandom article ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P646'), ('name', 'Freebase ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7033'), ('name', 'Australian Educational Vocabulary ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8408'), ('name', 'KBpedia ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8519'), ('name', 'RKD thesaurus ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8814'), ('name', 'WordNet 3.1 Synset ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P910'), ('name', "topic's main category")]
# [('p', 'http://www.wikidata.org/prop/direct/P950'), ('name', 'Biblioteca Nacional de España ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P867'), ('name', 'ROME Occupation Code (v3)')]
# 32

# %%
# we're now trying with the properties of author
queryString = """
SELECT DISTINCT ?p ?name 
WHERE {
   # bind something
    wd:Q482980 ?p ?obj .
   # get the label
   # ?p sc:name ?name .
}
LIMIT 50
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P1014'), ('name', 'Art & Architecture Thesaurus ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1051'), ('name', 'PSH ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1225'), ('name', 'U.S. National Archives Identifier')]
# [('p', 'http://www.wikidata.org/prop/direct/P1245'), ('name', 'OmegaWiki Defined Meaning')]
# [('p', 'http://www.wikidata.org/prop/direct/P1256'), ('name', 'Iconclass notation')]
# [('p', 'http://www.wikidata.org/prop/direct/P1417'), ('name', 'Encyclopædia Britannica Online ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1552'), ('name', 'has quality')]
# [('p', 'http://www.wikidata.org/prop/direct/P1687'), ('name', 'Wikidata property')]
# [('p', 'http://www.wikidata.org/prop/direct/P1889'), ('name', 'different from')]
# [('p', 'http://www.wikidata.org/prop/direct/P227'), ('name', 'GND ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P244'), ('name', 'Library of Congress authority ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2581'), ('name', 'BabelNet ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P268'), ('name', 'Bibliothèque nationale de France ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('name', 'subclass of')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('name', 'instance of')]
# [('p', 'http://www.wikidata.org/prop/direct/P3219'), ('name', 'Encyclopædia Universalis ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3222'), ('name', 'NE.se ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P373'), ('name', 'Commons category')]
# [('p', 'http://www.wikidata.org/prop/direct/P3827'), ('name', 'JSTOR topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3916'), ('name', 'UNESCO Thesaurus ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P4342'), ('name', 'Store norske leksikon ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P4613'), ('name', 'Encyclopedia of Modern Ukraine ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P4801'), ('name', 'LoC and MARC vocabularies ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P4839'), ('name', 'Wolfram Language entity code')]
# [('p', 'http://www.wikidata.org/prop/direct/P5019'), ('name', 'Brockhaus Enzyklopädie online ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P508'), ('name', 'BNCF Thesaurus ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5398'), ('name', 'TDKIV term ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5869'), ('name', 'model item')]
# [('p', 'http://www.wikidata.org/prop/direct/P6186'), ('name', 'category for eponymous categories')]
# [('p', 'http://www.wikidata.org/prop/direct/P646'), ('name', 'Freebase ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7818'), ('name', 'French Vikidia ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7982'), ('name', 'Hrvatska enciklopedija ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8408'), ('name', 'KBpedia ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8519'), ('name', 'RKD thesaurus ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8814'), ('name', 'WordNet 3.1 Synset ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P910'), ('name', "topic's main category")]
# [('p', 'http://www.wikidata.org/prop/direct/P9318'), ('name', 'Ávvir topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P950'), ('name', 'Biblioteca Nacional de España ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P952'), ('name', 'ISCO-88 occupation code')]
# 39

# %%
#trying with the properties of Dante?
# we didn't find literary movement but we find movement
queryString = """
SELECT DISTINCT ?p ?name
WHERE {
   # bind something
   wd:Q1067 ?p ?o . 
   # get the label
   # ?p sc:name ?name .
   FILTER(!isLiteral(?o)) .
}
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P101'), ('name', 'field of work')]
# [('p', 'http://www.wikidata.org/prop/direct/P103'), ('name', 'native language')]
# [('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('p', 'http://www.wikidata.org/prop/direct/P1066'), ('name', 'student of')]
# [('p', 'http://www.wikidata.org/prop/direct/P119'), ('name', 'place of burial')]
# [('p', 'http://www.wikidata.org/prop/direct/P1196'), ('name', 'manner of death')]
# [('p', 'http://www.wikidata.org/prop/direct/P1299'), ('name', 'depicted by')]
# [('p', 'http://www.wikidata.org/prop/direct/P1343'), ('name', 'described by source')]
# [('p', 'http://www.wikidata.org/prop/direct/P135'), ('name', 'movement')]
# [('p', 'http://www.wikidata.org/prop/direct/P140'), ('name', 'religion')]
# [('p', 'http://www.wikidata.org/prop/direct/P1412'), ('name', 'languages spoken, written or signed')]
# [('p', 'http://www.wikidata.org/prop/direct/P172'), ('name', 'ethnic group')]
# [('p', 'http://www.wikidata.org/prop/direct/P18'), ('name', 'image')]
# [('p', 'http://www.wikidata.org/prop/direct/P19'), ('name', 'place of birth')]
# [('p', 'http://www.wikidata.org/prop/direct/P20'), ('name', 'place of death')]
# [('p', 'http://www.wikidata.org/prop/direct/P21'), ('name', 'sex or gender')]
# [('p', 'http://www.wikidata.org/prop/direct/P22'), ('name', 'father')]
# [('p', 'http://www.wikidata.org/prop/direct/P25'), ('name', 'mother')]
# [('p', 'http://www.wikidata.org/prop/direct/P26'), ('name', 'spouse')]
# [('p', 'http://www.wikidata.org/prop/direct/P27'), ('name', 'country of citizenship')]
# 20

# %%
# let's take a look at what it is for Dante
queryString = """
SELECT DISTINCT ?o ?name
WHERE {
   # bind something
   wd:Q1067 wdt:P135 ?o . 
   # get the label
   # ?o sc:name ?name .
}
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('o', 'http://www.wikidata.org/entity/Q542036'), ('name', 'Dolce Stil Novo')]
# 1

# %% [markdown]
# Final query for this task

# %%
# write your final query
queryString = """
SELECT DISTINCT ?p ?namep ?o ?name
WHERE {
   # bind something
   wd:Q542036 ?p ?o . 
   # get the label
   # ?p sc:name ?namep .
   # ?o sc:name ?name .
}
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P495'), ('namep', 'country of origin'), ('o', 'http://www.wikidata.org/entity/Q38'), ('name', 'Italy')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('namep', 'instance of'), ('o', 'http://www.wikidata.org/entity/Q3326717'), ('name', 'literary movement')]
# 2

# %% [markdown]
# ## Task 4
# Return the poets born in the same place of the author of The Divine Comedy who are born between 1300 and 1500 (1300 and 1500 included) (the result set must be a list of couples poets IRI and label).

# %%
# write your queries
#We want to find birthplace and birthdate retrieving the property of Dante
queryString = """
SELECT DISTINCT ?p ?name 
WHERE {
   # bind something
   wd:Q1067 ?p ?obj .
   # get the label
   # ?p sc:name ?name .
   FILTER REGEX (?name, ".*birth.*")
}
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P19'), ('name', 'place of birth')]
# [('p', 'http://www.wikidata.org/prop/direct/P569'), ('name', 'date of birth')]
# 2

# %%
#We're decomposing the final query in 2 to be sure.
queryString = """
SELECT DISTINCT ?poet ?name ?year
WHERE {
   # bind something
   # ?poet wdt:P106 wd:Q49757 ; 
       sc:name ?name ;   
       wdt:P569 ?year .
   
   FILTER(?year > "1299"^^xsd:gYear && ?year < "1501"^^xsd:gYear)
}
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('poet', 'http://www.wikidata.org/entity/Q3296224'), ('name', 'Muhammad ibn Mahmud Amuli'), ('year', '1300-01-01T00:00:00Z')]
# [('poet', 'http://www.wikidata.org/entity/Q18214823'), ('name', 'Georges Warda'), ('year', '1300-01-01T00:00:00Z')]
# [('poet', 'http://www.wikidata.org/entity/Q1510346'), ('name', 'Gerbert de Montreuil'), ('year', '1300-01-01T00:00:00Z')]
# [('poet', 'http://www.wikidata.org/entity/Q5199'), ('name', 'Le Chastelain de Couci'), ('year', '1300-01-01T00:00:00Z')]
# [('poet', 'http://www.wikidata.org/entity/Q582581'), ('name', 'Tomaso di Sasso'), ('year', '1300-01-01T00:00:00Z')]
# [('poet', 'http://www.wikidata.org/entity/Q734140'), ('name', 'Walter of Winterburn'), ('year', '1300-01-01T00:00:00Z')]
# [('poet', 'http://www.wikidata.org/entity/Q7461783'), ('name', 'Shahin Shirazi'), ('year', '1300-01-01T00:00:00Z')]
# [('poet', 'http://www.wikidata.org/entity/Q6043494'), ('name', 'Mustafa Zarir'), ('year', '1301-01-01T00:00:00Z')]
# [('poet', 'http://www.wikidata.org/entity/Q2245720'), ('name', "Cielo d'Alcamo"), ('year', '1300-01-01T00:00:00Z')]
# [('poet', 'http://www.wikidata.org/entity/Q711416'), ('name', 'Trần Minh Tông'), ('year', '1300-09-04T00:00:00Z')]
# [('poet', 'http://www.wikidata.org/entity/Q930623'), ('name', 'Gautier de Metz'), ('year', '1300-01-01T00:00:00Z')]
# [('poet', 'http://www.wikidata.org/entity/Q4321424'), ('name', 'Nina Siciliana'), ('year', '1300-01-01T00:00:00Z')]
# [('poet', 'http://www.wikidata.org/entity/Q2640054'), ('name', 'Albrecht von Kemenaten'), ('year', '1300-01-01T00:00:00Z')]
# [('poet', 'http://www.wikidata.org/entity/Q3629743'), ('name', 'Auliver'), ('year', '1300-01-01T00:00:00Z')]
# [('poet', 'http://www.wikidata.org/entity/Q3610547'), ('name', 'Alexios Makrembolites'), ('year', '1301-01-01T00:00:00Z')]
# [('poet', 'http://www.wikidata.org/entity/Q7936667'), ('name', 'Viswanatha Kaviraja'), ('year', '1300-01-01T00:00:00Z')]
# [('poet', 'http://www.wikidata.org/entity/Q16742870'), ('name', 'Gotto Mantovano'), ('year', '1301-01-01T00:00:00Z')]
# [('poet', 'http://www.wikidata.org/entity/Q200580'), ('name', 'Guillaume de Machaut'), ('year', '1300-01-01T00:00:00Z')]
# [('poet', 'http://www.wikidata.org/entity/Q3436655'), ('name', 'Robert de Gretham'), ('year', '1300-01-01T00:00:00Z')]
# [('poet', 'http://www.wikidata.org/entity/Q3854784'), ('name', 'Meo Abbracciavacca'), ('year', '1300-01-01T00:00:00Z')]
# 20

# %%
#retrieving all the poets born at the same place as Dante
queryString = """
SELECT DISTINCT ?poet ?name ?birthplace ?city
WHERE {
   # bind something
   # ?poet wdt:P106 wd:Q49757 ; 
       sc:name ?name ;   
       wdt:P19 ?birthplace .
    # ?birthplace sc:name ?city .
   wd:Q1067 wdt:P19 ?birthplaceD . #retrieve the birthplace of Dante
   
   FILTER(?birthplace = ?birthplaceD)
}
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('poet', 'http://www.wikidata.org/entity/Q17203201'), ('name', 'Sebastiano Fenzi'), ('birthplace', 'http://www.wikidata.org/entity/Q2044'), ('city', 'Florence')]
# [('poet', 'http://www.wikidata.org/entity/Q21003797'), ('name', 'Michel Verin'), ('birthplace', 'http://www.wikidata.org/entity/Q2044'), ('city', 'Florence')]
# [('poet', 'http://www.wikidata.org/entity/Q426305'), ('name', 'Giovanni Maria Cecchi'), ('birthplace', 'http://www.wikidata.org/entity/Q2044'), ('city', 'Florence')]
# [('poet', 'http://www.wikidata.org/entity/Q1248954'), ('name', 'Giovanni di Bernardo Rucellai'), ('birthplace', 'http://www.wikidata.org/entity/Q2044'), ('city', 'Florence')]
# [('poet', 'http://www.wikidata.org/entity/Q7803'), ('name', 'Bronzino'), ('birthplace', 'http://www.wikidata.org/entity/Q2044'), ('city', 'Florence')]
# [('poet', 'http://www.wikidata.org/entity/Q1067'), ('name', 'Dante Alighieri'), ('birthplace', 'http://www.wikidata.org/entity/Q2044'), ('city', 'Florence')]
# [('poet', 'http://www.wikidata.org/entity/Q177854'), ('name', "Lorenzo de' Medici"), ('birthplace', 'http://www.wikidata.org/entity/Q2044'), ('city', 'Florence')]
# [('poet', 'http://www.wikidata.org/entity/Q529858'), ('name', 'Giovanni Papini'), ('birthplace', 'http://www.wikidata.org/entity/Q2044'), ('city', 'Florence')]
# [('poet', 'http://www.wikidata.org/entity/Q3694295'), ('name', 'Corrado Pavolini'), ('birthplace', 'http://www.wikidata.org/entity/Q2044'), ('city', 'Florence')]
# [('poet', 'http://www.wikidata.org/entity/Q328117'), ('name', 'Girolamo Benivieni'), ('birthplace', 'http://www.wikidata.org/entity/Q2044'), ('city', 'Florence')]
# [('poet', 'http://www.wikidata.org/entity/Q104145408'), ('name', 'Luigi Alamanni'), ('birthplace', 'http://www.wikidata.org/entity/Q2044'), ('city', 'Florence')]
# [('poet', 'http://www.wikidata.org/entity/Q721846'), ('name', 'Luigi Alamanni'), ('birthplace', 'http://www.wikidata.org/entity/Q2044'), ('city', 'Florence')]
# [('poet', 'http://www.wikidata.org/entity/Q1249317'), ('name', 'Lorenzo Lippi'), ('birthplace', 'http://www.wikidata.org/entity/Q2044'), ('city', 'Florence')]
# [('poet', 'http://www.wikidata.org/entity/Q366328'), ('name', 'Brunetto Latini'), ('birthplace', 'http://www.wikidata.org/entity/Q2044'), ('city', 'Florence')]
# [('poet', 'http://www.wikidata.org/entity/Q3742647'), ('name', 'Ferdinando Paolieri'), ('birthplace', 'http://www.wikidata.org/entity/Q2044'), ('city', 'Florence')]
# [('poet', 'http://www.wikidata.org/entity/Q509504'), ('name', 'Franco Fortini'), ('birthplace', 'http://www.wikidata.org/entity/Q2044'), ('city', 'Florence')]
# [('poet', 'http://www.wikidata.org/entity/Q117197'), ('name', 'Marc Monnier'), ('birthplace', 'http://www.wikidata.org/entity/Q2044'), ('city', 'Florence')]
# [('poet', 'http://www.wikidata.org/entity/Q1399'), ('name', 'Niccolò Machiavelli'), ('birthplace', 'http://www.wikidata.org/entity/Q2044'), ('city', 'Florence')]
# [('poet', 'http://www.wikidata.org/entity/Q3610195'), ('name', 'Alessandro Parronchi'), ('birthplace', 'http://www.wikidata.org/entity/Q2044'), ('city', 'Florence')]
# [('poet', 'http://www.wikidata.org/entity/Q335896'), ('name', 'John Douglas, 9th Marquess of Queensberry'), ('birthplace', 'http://www.wikidata.org/entity/Q2044'), ('city', 'Florence')]
# 20

# %% [markdown]
# Final query for this task

# %%
# write your final query
queryString = """
SELECT DISTINCT ?poet ?name
WHERE {
   # bind something
   # ?poet wdt:P106 wd:Q49757 ; 
       sc:name ?name ;   
       wdt:P569 ?year ;
       wdt:P19 ?birthplace .
   wd:Q1067 wdt:P19 ?birthplaceD . #retrieve the birthplace of Dante
   
   FILTER(?year > "1299"^^xsd:gYear && ?year < "1501"^^xsd:gYear && ?birthplace = ?birthplaceD)
}
LIMIT 50
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('poet', 'http://www.wikidata.org/entity/Q21003797'), ('name', 'Michel Verin')]
# [('poet', 'http://www.wikidata.org/entity/Q1248954'), ('name', 'Giovanni di Bernardo Rucellai')]
# [('poet', 'http://www.wikidata.org/entity/Q177854'), ('name', "Lorenzo de' Medici")]
# [('poet', 'http://www.wikidata.org/entity/Q328117'), ('name', 'Girolamo Benivieni')]
# [('poet', 'http://www.wikidata.org/entity/Q721846'), ('name', 'Luigi Alamanni')]
# [('poet', 'http://www.wikidata.org/entity/Q1399'), ('name', 'Niccolò Machiavelli')]
# [('poet', 'http://www.wikidata.org/entity/Q366499'), ('name', 'Orcagna')]
# [('poet', 'http://www.wikidata.org/entity/Q1402'), ('name', 'Giovanni Boccaccio')]
# [('poet', 'http://www.wikidata.org/entity/Q631635'), ('name', 'Luigi Pulci')]
# [('poet', 'http://www.wikidata.org/entity/Q2857170'), ('name', 'Antonio Alamanni')]
# [('poet', 'http://www.wikidata.org/entity/Q1527917'), ('name', 'Giuliano Dati')]
# [('poet', 'http://www.wikidata.org/entity/Q45539848'), ('name', 'Niccolò Tinucci')]
# [('poet', 'http://www.wikidata.org/entity/Q1113645'), ('name', 'Lucrezia Tornabuoni')]
# [('poet', 'http://www.wikidata.org/entity/Q711964'), ('name', 'Cristoforo Landino')]
# [('poet', 'http://www.wikidata.org/entity/Q741841'), ('name', 'Ugolino di Vieri')]
# [('poet', 'http://www.wikidata.org/entity/Q3677259'), ('name', 'Cino Rinuccini')]
# [('poet', 'http://www.wikidata.org/entity/Q640594'), ('name', 'John Dominici')]
# [('poet', 'http://www.wikidata.org/entity/Q781511'), ('name', 'Aurelio Lippo Brandolini')]
# [('poet', 'http://www.wikidata.org/entity/Q13570581'), ('name', 'Bartolomeo della Fonte')]
# [('poet', 'http://www.wikidata.org/entity/Q302218'), ('name', 'Agnolo Firenzuola')]
# [('poet', 'http://www.wikidata.org/entity/Q62055718'), ('name', "Lippo Pasci de' Bardi")]
# [('poet', 'http://www.wikidata.org/entity/Q19357719'), ('name', 'Lodovico Martelli')]
# [('poet', 'http://www.wikidata.org/entity/Q425969'), ('name', 'Bernardo Bellincioni')]
# [('poet', 'http://www.wikidata.org/entity/Q1229872'), ('name', 'Matteo Palmieri')]
# [('poet', 'http://www.wikidata.org/entity/Q589545'), ('name', 'Bernardo Pulci')]
# [('poet', 'http://www.wikidata.org/entity/Q1215784'), ('name', 'Alessandra Scala')]
# [('poet', 'http://www.wikidata.org/entity/Q659093'), ('name', 'Benedetto Dei')]
# [('poet', 'http://www.wikidata.org/entity/Q50399164'), ('name', "Dolcibene de' Tori")]
# [('poet', 'http://www.wikidata.org/entity/Q1149308'), ('name', 'Rustico Filippi')]
# [('poet', 'http://www.wikidata.org/entity/Q3830353'), ('name', 'Leonardo Dati')]
# [('poet', 'http://www.wikidata.org/entity/Q66809563'), ('name', "Alessandro Pazzi de' Medici")]
# [('poet', 'http://www.wikidata.org/entity/Q604448'), ('name', 'Antonio Pucci')]
# [('poet', 'http://www.wikidata.org/entity/Q2832756'), ('name', 'Alessandro Braccesi')]
# [('poet', 'http://www.wikidata.org/entity/Q3750836'), ('name', "Francesco d'Altobianco Alberti")]
# [('poet', 'http://www.wikidata.org/entity/Q1058842'), ('name', 'Domenico di Giovanni')]
# [('poet', 'http://www.wikidata.org/entity/Q1158784'), ('name', 'Crinitus')]
# [('poet', 'http://www.wikidata.org/entity/Q17166727'), ('name', 'Antonio di Meglio')]
# [('poet', 'http://www.wikidata.org/entity/Q15633606'), ('name', 'Bondie Dietaiuti')]
# [('poet', 'http://www.wikidata.org/entity/Q3339583'), ('name', 'Niccolò Martelli')]
# [('poet', 'http://www.wikidata.org/entity/Q3763435'), ('name', 'Gianni Alfani')]
# [('poet', 'http://www.wikidata.org/entity/Q3068447'), ('name', 'Feo Belcari')]
# [('poet', 'http://www.wikidata.org/entity/Q18945288'), ('name', 'Francesco da Firenze')]
# 42

# %% [markdown]
# ## Task 5
# Identify the BGP for literary work

# %%
# write your queries
# looking for the objects of which The Divine Comedy is an instance of
queryString = """
SELECT DISTINCT ?obj ?name
WHERE {
   # bind something
   wd:Q40185 wdt:P31 ?obj .
   # get the label
   # ?obj sc:name ?name.
}
LIMIT 50
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('obj', 'http://www.wikidata.org/entity/Q47461344'), ('name', 'written work')]
# 1

# %% [markdown]
# Final query for this task

# %%
# write your final query
# we're retrieving all properties and objects of written work
queryString = """
SELECT DISTINCT ?p ?name ?obj ?nameo
WHERE {
   # bind something
   wd:Q47461344 ?p ?obj .
   # get the label
   # ?p sc:name ?name .
   # ?obj sc:name ?nameo .
}
LIMIT 50
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('name', 'properties for this type'), ('obj', 'http://www.wikidata.org/entity/P214'), ('nameo', 'VIAF ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('name', 'properties for this type'), ('obj', 'http://www.wikidata.org/entity/P407'), ('nameo', 'language of work or name')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('name', 'subclass of'), ('obj', 'http://www.wikidata.org/entity/Q17537576'), ('nameo', 'creative work')]
# [('p', 'http://www.wikidata.org/prop/direct/P1889'), ('name', 'different from'), ('obj', 'http://www.wikidata.org/entity/Q7725634'), ('nameo', 'literary work')]
# [('p', 'http://www.wikidata.org/prop/direct/P1889'), ('name', 'different from'), ('obj', 'http://www.wikidata.org/entity/Q3331189'), ('nameo', 'version, edition, or translation')]
# [('p', 'http://www.wikidata.org/prop/direct/P1889'), ('name', 'different from'), ('obj', 'http://www.wikidata.org/entity/Q571'), ('nameo', 'book')]
# [('p', 'http://www.wikidata.org/prop/direct/P2283'), ('name', 'uses'), ('obj', 'http://www.wikidata.org/entity/Q8192'), ('nameo', 'writing system')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('name', 'properties for this type'), ('obj', 'http://www.wikidata.org/entity/P136'), ('nameo', 'genre')]
# [('p', 'http://www.wikidata.org/prop/direct/P910'), ('name', "topic's main category"), ('obj', 'http://www.wikidata.org/entity/Q10013893'), ('nameo', 'Category:Written works')]
# [('p', 'http://www.wikidata.org/prop/direct/P1889'), ('name', 'different from'), ('obj', 'http://www.wikidata.org/entity/Q105763458'), ('nameo', 'volume')]
# 10

# %% [markdown]
# ## Task 6
# Compare the author of The Divine Comedy with Giovanni Boccaccio. Return for these poets the number of literary work they wrote (the result set must be two triples -one for each author- author IRI, label and #literary work).

# %%
# write your queries
#we're gonna retrieve what property link literary work and poet
queryString = """
SELECT DISTINCT  ?p ?name 
WHERE { 
   # bind something
   # ?poet wdt:P106 wd:Q49757;
         # ?p wd:Q7725634 .
   # ?p sc:name ?name .
} 
LIMIT 50 
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('name', 'instance of')]
# 1

# %%
#maybe the other way around
queryString = """
SELECT DISTINCT  ?p ?name 
WHERE { 
   # bind something
   # ?litwrk wdt:P31 wd:Q7725634 ;
           # ?p wd:Q49757 .
   # ?p sc:name ?name .
} 
LIMIT 50 
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('p', 'http://www.wikidata.org/prop/direct/P180'), ('name', 'depicts')]
# [('p', 'http://www.wikidata.org/prop/direct/P921'), ('name', 'main subject')]
# 3

# %%
#not finding anything, we're trying to retrieve every property from literary work
#and we find author(and creator, don't know what is the difference between both)
queryString = """
SELECT DISTINCT  ?p ?name 
WHERE { 
   # bind something
   # ?litwrk wdt:P31 wd:Q7725634 ;
           # ?p ?o .
   # ?p sc:name ?name .
   FILTER(!isLiteral(?o)) .
} 
LIMIT 40 
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P110'), ('name', 'illustrator')]
# [('p', 'http://www.wikidata.org/prop/direct/P123'), ('name', 'publisher')]
# [('p', 'http://www.wikidata.org/prop/direct/P1269'), ('name', 'facet of')]
# [('p', 'http://www.wikidata.org/prop/direct/P1343'), ('name', 'described by source')]
# [('p', 'http://www.wikidata.org/prop/direct/P136'), ('name', 'genre')]
# [('p', 'http://www.wikidata.org/prop/direct/P138'), ('name', 'named after')]
# [('p', 'http://www.wikidata.org/prop/direct/P140'), ('name', 'religion')]
# [('p', 'http://www.wikidata.org/prop/direct/P1411'), ('name', 'nominated for')]
# [('p', 'http://www.wikidata.org/prop/direct/P1424'), ('name', "topic's main template")]
# [('p', 'http://www.wikidata.org/prop/direct/P1434'), ('name', 'takes place in fictional universe')]
# [('p', 'http://www.wikidata.org/prop/direct/P144'), ('name', 'based on')]
# [('p', 'http://www.wikidata.org/prop/direct/P155'), ('name', 'follows')]
# [('p', 'http://www.wikidata.org/prop/direct/P156'), ('name', 'followed by')]
# [('p', 'http://www.wikidata.org/prop/direct/P166'), ('name', 'award received')]
# [('p', 'http://www.wikidata.org/prop/direct/P17'), ('name', 'country')]
# [('p', 'http://www.wikidata.org/prop/direct/P170'), ('name', 'creator')]
# [('p', 'http://www.wikidata.org/prop/direct/P179'), ('name', 'part of the series')]
# [('p', 'http://www.wikidata.org/prop/direct/P18'), ('name', 'image')]
# [('p', 'http://www.wikidata.org/prop/direct/P1889'), ('name', 'different from')]
# [('p', 'http://www.wikidata.org/prop/direct/P195'), ('name', 'collection')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('name', 'subclass of')]
# [('p', 'http://www.wikidata.org/prop/direct/P291'), ('name', 'place of publication')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('name', 'instance of')]
# [('p', 'http://www.wikidata.org/prop/direct/P361'), ('name', 'part of')]
# [('p', 'http://www.wikidata.org/prop/direct/P407'), ('name', 'language of work or name')]
# [('p', 'http://www.wikidata.org/prop/direct/P443'), ('name', 'pronunciation audio')]
# [('p', 'http://www.wikidata.org/prop/direct/P495'), ('name', 'country of origin')]
# [('p', 'http://www.wikidata.org/prop/direct/P4969'), ('name', 'derivative work')]
# [('p', 'http://www.wikidata.org/prop/direct/P50'), ('name', 'author')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('name', 'has part')]
# [('p', 'http://www.wikidata.org/prop/direct/P6216'), ('name', 'copyright status')]
# [('p', 'http://www.wikidata.org/prop/direct/P655'), ('name', 'translator')]
# [('p', 'http://www.wikidata.org/prop/direct/P674'), ('name', 'characters')]
# [('p', 'http://www.wikidata.org/prop/direct/P747'), ('name', 'has edition or translation')]
# [('p', 'http://www.wikidata.org/prop/direct/P7937'), ('name', 'form of creative work')]
# [('p', 'http://www.wikidata.org/prop/direct/P8345'), ('name', 'media franchise')]
# [('p', 'http://www.wikidata.org/prop/direct/P840'), ('name', 'narrative location')]
# [('p', 'http://www.wikidata.org/prop/direct/P8411'), ('name', 'set in environment')]
# [('p', 'http://www.wikidata.org/prop/direct/P856'), ('name', 'official website')]
# [('p', 'http://www.wikidata.org/prop/direct/P88'), ('name', 'commissioned by')]
# 40

# %% [markdown]
# Final query for this task

# %%
# write your final query
# we found the BGP of Giovanni Boccaccio during the task 4
queryString = """
SELECT DISTINCT ?poet ?name (COUNT(?lwork) as ?nblworks) 
WHERE{ 
   # bind something
   # ?lwork wdt:P31 wd:Q7725634 ;
          wdt:P50 ?poet .
   # ?poet wdt:P106 wd:Q49757 ;
        sc:name ?name .
   FILTER (?poet IN (wd:Q1402, wd:Q1067)) .
} ORDER BY DESC(?nblworks)
LIMIT 50 
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('poet', 'http://www.wikidata.org/entity/Q1067'), ('name', 'Dante Alighieri'), ('nblworks', '37')]
# [('poet', 'http://www.wikidata.org/entity/Q1402'), ('name', 'Giovanni Boccaccio'), ('nblworks', '10')]
# 2

# %% [markdown]
# ## Task 7
# Consider italian poets, their place of birth (the city) and their university education. Return for each city the number of poets who born there and who was educated there (the result set must be a list of triples city IRI, label and #poets).

# %%
# write your queries
# First we need to find the BGP of Italian nationality. We just need to retrieve the nationality of Dante
# It was not Italy at the time
queryString = """
SELECT DISTINCT ?o ?name
WHERE {
   # bind something
   wd:Q1067 wdt:P27 ?o . 
   # get the label
   # ?o sc:name ?name.
}
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('o', 'http://www.wikidata.org/entity/Q148540'), ('name', 'Republic of Florence')]
# 1

# %%
#we got the PGB of country above, we're just gonna use it on the birthplace of Dante to obtain the PGB of Italy
queryString = """
SELECT DISTINCT ?country ?name
WHERE {
   # bind something
   wd:Q1067 wdt:P19 ?city. 
   # get the label
   # ?city wdt:P17 ?country.
   # ?country sc:name ?name.
}
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('country', 'http://www.wikidata.org/entity/Q38'), ('name', 'Italy')]
# 1

# %%
# we also need the BGP of university education
# We're gonna try to find the BGP of city to see its subclasses
queryString = """
SELECT DISTINCT ?city ?name
WHERE {
   # bind something
   # ?born wdt:P19 ?pot . 
   # ?pot wdt:P31 ?type .
   # ?type wdt:P279 ?city .
   # ?city sc:name ?name .
}
LIMIT 50
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('city', 'http://www.wikidata.org/entity/Q12081657'), ('name', 'township level division of the Republic of China')]
# [('city', 'http://www.wikidata.org/entity/Q14502790'), ('name', 'settlement of Hungary')]
# [('city', 'http://www.wikidata.org/entity/Q22580836'), ('name', 'village in Latvia')]
# [('city', 'http://www.wikidata.org/entity/Q717478'), ('name', 'administrative territorial entity of the United Kingdom')]
# [('city', 'http://www.wikidata.org/entity/Q683738'), ('name', 'Administrative subdivision of Wales')]
# [('city', 'http://www.wikidata.org/entity/Q2828312'), ('name', 'protected area of Canada')]
# [('city', 'http://www.wikidata.org/entity/Q10677154'), ('name', 'Stadsdelsnämndsområde')]
# [('city', 'http://www.wikidata.org/entity/Q35798'), ('name', 'executive branch')]
# [('city', 'http://www.wikidata.org/entity/Q57058'), ('name', 'municipalities of Croatia')]
# [('city', 'http://www.wikidata.org/entity/Q15989253'), ('name', 'part')]
# [('city', 'http://www.wikidata.org/entity/Q19953632'), ('name', 'former administrative territorial entity')]
# [('city', 'http://www.wikidata.org/entity/Q1030034'), ('name', 'GLAM')]
# [('city', 'http://www.wikidata.org/entity/Q15078955'), ('name', 'urban-type settlement in Russia')]
# [('city', 'http://www.wikidata.org/entity/Q164142'), ('name', 'protectorate')]
# [('city', 'http://www.wikidata.org/entity/Q171308'), ('name', 'oblast')]
# [('city', 'http://www.wikidata.org/entity/Q4286337'), ('name', 'city district')]
# [('city', 'http://www.wikidata.org/entity/Q10374501'), ('name', 'administrative territorial entity of Bulgaria')]
# [('city', 'http://www.wikidata.org/entity/Q14757767'), ('name', 'fourth-level administrative country subdivision')]
# [('city', 'http://www.wikidata.org/entity/Q264441'), ('name', 'Bezirk')]
# [('city', 'http://www.wikidata.org/entity/Q269528'), ('name', 'unincorporated area')]
# [('city', 'http://www.wikidata.org/entity/Q387917'), ('name', 'administrative territorial entity of Germany')]
# [('city', 'http://www.wikidata.org/entity/Q417633'), ('name', 'self-governance')]
# [('city', 'http://www.wikidata.org/entity/Q1054813'), ('name', 'municipality of Japan')]
# [('city', 'http://www.wikidata.org/entity/Q1850442'), ('name', 'administrative territorial entity of Japan')]
# [('city', 'http://www.wikidata.org/entity/Q470540'), ('name', 'seat')]
# [('city', 'http://www.wikidata.org/entity/Q4976993'), ('name', 'civil parish')]
# [('city', 'http://www.wikidata.org/entity/Q294440'), ('name', 'public space')]
# [('city', 'http://www.wikidata.org/entity/Q588140'), ('name', 'science museum')]
# [('city', 'http://www.wikidata.org/entity/Q102496'), ('name', 'parish')]
# [('city', 'http://www.wikidata.org/entity/Q697379'), ('name', 'administrative territorial entity of Romania')]
# [('city', 'http://www.wikidata.org/entity/Q1048835'), ('name', 'political territorial entity')]
# [('city', 'http://www.wikidata.org/entity/Q10864048'), ('name', 'first-level administrative country subdivision')]
# [('city', 'http://www.wikidata.org/entity/Q1093829'), ('name', 'city of the United States')]
# [('city', 'http://www.wikidata.org/entity/Q123705'), ('name', 'neighborhood')]
# [('city', 'http://www.wikidata.org/entity/Q13539802'), ('name', 'place with town rights and privileges')]
# [('city', 'http://www.wikidata.org/entity/Q15284'), ('name', 'municipality')]
# [('city', 'http://www.wikidata.org/entity/Q1549591'), ('name', 'big city')]
# [('city', 'http://www.wikidata.org/entity/Q192611'), ('name', 'electoral district')]
# [('city', 'http://www.wikidata.org/entity/Q2039348'), ('name', 'municipality of the Netherlands')]
# [('city', 'http://www.wikidata.org/entity/Q205895'), ('name', 'landmass')]
# [('city', 'http://www.wikidata.org/entity/Q2074737'), ('name', 'municipality of Spain')]
# [('city', 'http://www.wikidata.org/entity/Q2221906'), ('name', 'geographic location')]
# [('city', 'http://www.wikidata.org/entity/Q262166'), ('name', 'municipality of Germany')]
# [('city', 'http://www.wikidata.org/entity/Q3183364'), ('name', 'administrative territorial entity of Spain')]
# [('city', 'http://www.wikidata.org/entity/Q3702971'), ('name', 'personal data')]
# [('city', 'http://www.wikidata.org/entity/Q3957'), ('name', 'town')]
# [('city', 'http://www.wikidata.org/entity/Q486972'), ('name', 'human settlement')]
# [('city', 'http://www.wikidata.org/entity/Q4946461'), ('name', 'spa town')]
# [('city', 'http://www.wikidata.org/entity/Q515'), ('name', 'city')]
# [('city', 'http://www.wikidata.org/entity/Q532'), ('name', 'village')]
# 50

# %%
# not what I'm looking for.
queryString = """
SELECT DISTINCT ?city ?name
WHERE {
   # bind something
   # ?city wdt:P279 wd:Q515 ;
       sc:name ?name .
}
LIMIT 50
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('city', 'http://www.wikidata.org/entity/Q15260353'), ('name', 'host city')]
# [('city', 'http://www.wikidata.org/entity/Q5124027'), ('name', 'city proper')]
# [('city', 'http://www.wikidata.org/entity/Q1656724'), ('name', 'ideal city')]
# [('city', 'http://www.wikidata.org/entity/Q83020'), ('name', 'provincial city')]
# [('city', 'http://www.wikidata.org/entity/Q28659128'), ('name', 'city of North Korea')]
# [('city', 'http://www.wikidata.org/entity/Q63208555'), ('name', 'city in Gabon')]
# [('city', 'http://www.wikidata.org/entity/Q104157'), ('name', 'city of the Philippines')]
# [('city', 'http://www.wikidata.org/entity/Q23640644'), ('name', 'Levitical city')]
# [('city', 'http://www.wikidata.org/entity/Q13218690'), ('name', 'town in Hungary')]
# [('city', 'http://www.wikidata.org/entity/Q15141632'), ('name', 'Thesaban Nakhon')]
# [('city', 'http://www.wikidata.org/entity/Q37800986'), ('name', 'Serbian city')]
# [('city', 'http://www.wikidata.org/entity/Q16858213'), ('name', 'town in Romania')]
# [('city', 'http://www.wikidata.org/entity/Q1266029'), ('name', 'edge city')]
# [('city', 'http://www.wikidata.org/entity/Q4943467'), ('name', 'Boomburb')]
# [('city', 'http://www.wikidata.org/entity/Q5770918'), ('name', 'city of Argentina')]
# [('city', 'http://www.wikidata.org/entity/Q63209072'), ('name', 'city in Colombia')]
# [('city', 'http://www.wikidata.org/entity/Q2367508'), ('name', 'township of Taiwan')]
# [('city', 'http://www.wikidata.org/entity/Q24700892'), ('name', 'post town')]
# [('city', 'http://www.wikidata.org/entity/Q1093829'), ('name', 'city of the United States')]
# [('city', 'http://www.wikidata.org/entity/Q1187811'), ('name', 'college town')]
# [('city', 'http://www.wikidata.org/entity/Q1256805'), ('name', 'Drei-Flüsse-Stadt')]
# [('city', 'http://www.wikidata.org/entity/Q13416557'), ('name', 'Royal city in Polish–Lithuanian Commonwealth')]
# [('city', 'http://www.wikidata.org/entity/Q13539802'), ('name', 'place with town rights and privileges')]
# [('city', 'http://www.wikidata.org/entity/Q1549591'), ('name', 'big city')]
# [('city', 'http://www.wikidata.org/entity/Q15647906'), ('name', 'city of Portugal')]
# [('city', 'http://www.wikidata.org/entity/Q2264924'), ('name', 'port settlement')]
# [('city', 'http://www.wikidata.org/entity/Q250811'), ('name', 'sub-province-level division')]
# [('city', 'http://www.wikidata.org/entity/Q25412763'), ('name', 'city in Chile')]
# [('city', 'http://www.wikidata.org/entity/Q2616791'), ('name', 'urban municipality of Poland')]
# [('city', 'http://www.wikidata.org/entity/Q42744322'), ('name', 'urban municipality of Germany')]
# [('city', 'http://www.wikidata.org/entity/Q537250'), ('name', 'federal city')]
# [('city', 'http://www.wikidata.org/entity/Q54935504'), ('name', 'city of Switzerland')]
# [('city', 'http://www.wikidata.org/entity/Q55440238'), ('name', 'city in Alberta')]
# [('city', 'http://www.wikidata.org/entity/Q677678'), ('name', 'fortified town')]
# [('city', 'http://www.wikidata.org/entity/Q707813'), ('name', 'Hanseatic city')]
# [('city', 'http://www.wikidata.org/entity/Q748149'), ('name', 'prefecture-level city')]
# [('city', 'http://www.wikidata.org/entity/Q12102963'), ('name', 'city specifically designated in the state plan')]
# [('city', 'http://www.wikidata.org/entity/Q15273785'), ('name', 'Belgian municipality with the title of city')]
# [('city', 'http://www.wikidata.org/entity/Q3249005'), ('name', 'provincial city')]
# [('city', 'http://www.wikidata.org/entity/Q494721'), ('name', 'city of Japan')]
# [('city', 'http://www.wikidata.org/entity/Q7819319'), ('name', 'Czech municipality with expanded powers')]
# [('city', 'http://www.wikidata.org/entity/Q8452914'), ('name', 'district town')]
# [('city', 'http://www.wikidata.org/entity/Q3559093'), ('name', 'sanctuary city')]
# [('city', 'http://www.wikidata.org/entity/Q652360'), ('name', 'sustainable city')]
# [('city', 'http://www.wikidata.org/entity/Q1231558'), ('name', 'smart city')]
# [('city', 'http://www.wikidata.org/entity/Q108454687'), ('name', 'half million city')]
# [('city', 'http://www.wikidata.org/entity/Q262882'), ('name', 'statutory city of Austria')]
# [('city', 'http://www.wikidata.org/entity/Q713146'), ('name', 'County-administered city')]
# [('city', 'http://www.wikidata.org/entity/Q925381'), ('name', 'city with powiat rights')]
# [('city', 'http://www.wikidata.org/entity/Q34843301'), ('name', 'capital of county in Romania')]
# 50

# %%
# Another approach could be to see the relations between Dante and Florence(as we have the BGP of both) hoping Dante has studied is Florence.
# Apparently not.
queryString = """
SELECT DISTINCT ?p ?name
WHERE {
   # bind something
   wd:Q1067 ?p wd:Q2044 .
   # ?p sc:name ?name .
}
LIMIT 50
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P19'), ('name', 'place of birth')]
# [('p', 'http://www.wikidata.org/prop/direct/P551'), ('name', 'residence')]
# 2

# %%
#maybe Dante doesn't have the field city of education but Giovanni Boccaccio does?
#Apparently not
queryString = """
SELECT DISTINCT ?p ?name
WHERE {
   # bind something
   wd:Q1402 ?p ?o . 
   # get the label
   # ?p sc:name ?name .
   FILTER(!isLiteral(?o)) .
}
LIMIT 40
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P103'), ('name', 'native language')]
# [('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('p', 'http://www.wikidata.org/prop/direct/P1066'), ('name', 'student of')]
# [('p', 'http://www.wikidata.org/prop/direct/P119'), ('name', 'place of burial')]
# [('p', 'http://www.wikidata.org/prop/direct/P1343'), ('name', 'described by source')]
# [('p', 'http://www.wikidata.org/prop/direct/P1412'), ('name', 'languages spoken, written or signed')]
# [('p', 'http://www.wikidata.org/prop/direct/P1424'), ('name', "topic's main template")]
# [('p', 'http://www.wikidata.org/prop/direct/P172'), ('name', 'ethnic group')]
# [('p', 'http://www.wikidata.org/prop/direct/P18'), ('name', 'image')]
# [('p', 'http://www.wikidata.org/prop/direct/P19'), ('name', 'place of birth')]
# [('p', 'http://www.wikidata.org/prop/direct/P20'), ('name', 'place of death')]
# [('p', 'http://www.wikidata.org/prop/direct/P21'), ('name', 'sex or gender')]
# [('p', 'http://www.wikidata.org/prop/direct/P27'), ('name', 'country of citizenship')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('name', 'instance of')]
# [('p', 'http://www.wikidata.org/prop/direct/P3342'), ('name', 'significant person')]
# [('p', 'http://www.wikidata.org/prop/direct/P509'), ('name', 'cause of death')]
# [('p', 'http://www.wikidata.org/prop/direct/P6379'), ('name', 'has works in the collection')]
# [('p', 'http://www.wikidata.org/prop/direct/P6886'), ('name', 'writing language')]
# [('p', 'http://www.wikidata.org/prop/direct/P734'), ('name', 'family name')]
# [('p', 'http://www.wikidata.org/prop/direct/P735'), ('name', 'given name')]
# [('p', 'http://www.wikidata.org/prop/direct/P7763'), ('name', 'copyright status as a creator')]
# [('p', 'http://www.wikidata.org/prop/direct/P800'), ('name', 'notable work')]
# [('p', 'http://www.wikidata.org/prop/direct/P802'), ('name', 'student')]
# [('p', 'http://www.wikidata.org/prop/direct/P910'), ('name', "topic's main category")]
# 24

# %%
#Maybe the property student of can help us
#Seems to give the name of his teacher maybe this will bring us to a university
queryString = """
SELECT DISTINCT ?o ?name
WHERE {
   # bind something
   wd:Q1402 wdt:P1066 ?o . 
   # get the label
   # ?o sc:name ?name .
}
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('o', 'http://www.wikidata.org/entity/Q736348'), ('name', 'Cino da Pistoia')]
# 1

# %%
#we've obtained not only some universities but also the property educated at
queryString = """
SELECT DISTINCT ?p ?namep ?o ?name
WHERE {
   # bind something
   wd:Q736348 ?p ?o . 
   # get the label
   # ?p sc:name ?namep .
   # ?o sc:name ?name .
}
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P108'), ('namep', 'employer'), ('o', 'http://www.wikidata.org/entity/Q1245999'), ('name', 'University of Siena')]
# [('p', 'http://www.wikidata.org/prop/direct/P108'), ('namep', 'employer'), ('o', 'http://www.wikidata.org/entity/Q748085'), ('name', 'University of Perugia')]
# [('p', 'http://www.wikidata.org/prop/direct/P106'), ('namep', 'occupation'), ('o', 'http://www.wikidata.org/entity/Q1209498'), ('name', 'poet lawyer')]
# [('p', 'http://www.wikidata.org/prop/direct/P108'), ('namep', 'employer'), ('o', 'http://www.wikidata.org/entity/Q131262'), ('name', 'University of Bologna')]
# [('p', 'http://www.wikidata.org/prop/direct/P69'), ('namep', 'educated at'), ('o', 'http://www.wikidata.org/entity/Q131262'), ('name', 'University of Bologna')]
# [('p', 'http://www.wikidata.org/prop/direct/P106'), ('namep', 'occupation'), ('o', 'http://www.wikidata.org/entity/Q1622272'), ('name', 'university teacher')]
# [('p', 'http://www.wikidata.org/prop/direct/P106'), ('namep', 'occupation'), ('o', 'http://www.wikidata.org/entity/Q185351'), ('name', 'jurist')]
# [('p', 'http://www.wikidata.org/prop/direct/P1343'), ('namep', 'described by source'), ('o', 'http://www.wikidata.org/entity/Q19180675'), ('name', 'Small Brockhaus and Efron Encyclopedic Dictionary')]
# [('p', 'http://www.wikidata.org/prop/direct/P1412'), ('namep', 'languages spoken, written or signed'), ('o', 'http://www.wikidata.org/entity/Q397'), ('name', 'Latin')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('namep', 'instance of'), ('o', 'http://www.wikidata.org/entity/Q5'), ('name', 'human')]
# [('p', 'http://www.wikidata.org/prop/direct/P1343'), ('namep', 'described by source'), ('o', 'http://www.wikidata.org/entity/Q51955019'), ('name', 'BEIC Digital Library')]
# [('p', 'http://www.wikidata.org/prop/direct/P1343'), ('namep', 'described by source'), ('o', 'http://www.wikidata.org/entity/Q602358'), ('name', 'Brockhaus and Efron Encyclopedic Dictionary')]
# [('p', 'http://www.wikidata.org/prop/direct/P1412'), ('namep', 'languages spoken, written or signed'), ('o', 'http://www.wikidata.org/entity/Q652'), ('name', 'Italian')]
# [('p', 'http://www.wikidata.org/prop/direct/P21'), ('namep', 'sex or gender'), ('o', 'http://www.wikidata.org/entity/Q6581097'), ('name', 'male')]
# [('p', 'http://www.wikidata.org/prop/direct/P7763'), ('namep', 'copyright status as a creator'), ('o', 'http://www.wikidata.org/entity/Q71887839'), ('name', 'copyrights on works have expired')]
# [('p', 'http://www.wikidata.org/prop/direct/P108'), ('namep', 'employer'), ('o', 'http://www.wikidata.org/entity/Q820887'), ('name', 'University of Florence')]
# [('p', 'http://www.wikidata.org/prop/direct/P20'), ('namep', 'place of death'), ('o', 'http://www.wikidata.org/entity/Q13376'), ('name', 'Pistoia')]
# [('p', 'http://www.wikidata.org/prop/direct/P19'), ('namep', 'place of birth'), ('o', 'http://www.wikidata.org/entity/Q13376'), ('name', 'Pistoia')]
# [('p', 'http://www.wikidata.org/prop/direct/P1066'), ('namep', 'student of'), ('o', 'http://www.wikidata.org/entity/Q1226745'), ('name', 'Dinus de Rossonis')]
# [('p', 'http://www.wikidata.org/prop/direct/P735'), ('namep', 'given name'), ('o', 'http://www.wikidata.org/entity/Q3677254'), ('name', 'Cino')]
# 20

# %%
#we're looking at the University of Siena to find the PGB of university and see how it is linked to city
#we're retrieving the property located in the administrative territorial entity
queryString = """
SELECT DISTINCT ?p ?namep ?o ?name
WHERE {
   # bind something
   wd:Q1245999 ?p ?o . 
   # get the label
   # ?p sc:name ?namep .
   # ?o sc:name ?name .
}
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P463'), ('namep', 'member of'), ('o', 'http://www.wikidata.org/entity/Q19861084'), ('name', 'ORCID, Inc.')]
# [('p', 'http://www.wikidata.org/prop/direct/P159'), ('namep', 'headquarters location'), ('o', 'http://www.wikidata.org/entity/Q2751'), ('name', 'Siena')]
# [('p', 'http://www.wikidata.org/prop/direct/P131'), ('namep', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q2751'), ('name', 'Siena')]
# [('p', 'http://www.wikidata.org/prop/direct/P17'), ('namep', 'country'), ('o', 'http://www.wikidata.org/entity/Q38'), ('name', 'Italy')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('namep', 'instance of'), ('o', 'http://www.wikidata.org/entity/Q3918'), ('name', 'university')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('namep', 'instance of'), ('o', 'http://www.wikidata.org/entity/Q45400320'), ('name', 'open-access publisher')]
# [('p', 'http://www.wikidata.org/prop/direct/P2936'), ('namep', 'language used'), ('o', 'http://www.wikidata.org/entity/Q652'), ('name', 'Italian')]
# [('p', 'http://www.wikidata.org/prop/direct/P463'), ('namep', 'member of'), ('o', 'http://www.wikidata.org/entity/Q868940'), ('name', 'European University Association')]
# [('p', 'http://www.wikidata.org/prop/direct/P463'), ('namep', 'member of'), ('o', 'http://www.wikidata.org/entity/Q211620'), ('name', 'Coimbra Group')]
# [('p', 'http://www.wikidata.org/prop/direct/P1416'), ('namep', 'affiliation'), ('o', 'http://www.wikidata.org/entity/Q211620'), ('name', 'Coimbra Group')]
# [('p', 'http://www.wikidata.org/prop/direct/P4195'), ('namep', 'category for employees of the organization'), ('o', 'http://www.wikidata.org/entity/Q8884453'), ('name', 'Category:University of Siena faculty')]
# [('p', 'http://www.wikidata.org/prop/direct/P3876'), ('namep', 'category for alumni of educational institution'), ('o', 'http://www.wikidata.org/entity/Q9757751'), ('name', 'Category:University of Siena alumni')]
# [('p', 'http://www.wikidata.org/prop/direct/P910'), ('namep', "topic's main category"), ('o', 'http://www.wikidata.org/entity/Q8884451'), ('name', 'Category:University of Siena')]
# 13

# %%
#query without the city of education is working
queryString = """
SELECT DISTINCT ?birthplace ?city (COUNT(?poet) as ?nbpoets)
WHERE {
   # bind something
   # ?poet wdt:P106 wd:Q49757 ; #a poet
        sc:name ?name ;
        wdt:P19 ?birthplace .
   # ?birthplace sc:name ?city ;
           wdt:P17 wd:Q38 .
} ORDER BY DESC(?nbpoets)
LIMIT 20 
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('birthplace', 'http://www.wikidata.org/entity/Q220'), ('city', 'Rome'), ('nbpoets', '213')]
# [('birthplace', 'http://www.wikidata.org/entity/Q2044'), ('city', 'Florence'), ('nbpoets', '179')]
# [('birthplace', 'http://www.wikidata.org/entity/Q2634'), ('city', 'Naples'), ('nbpoets', '136')]
# [('birthplace', 'http://www.wikidata.org/entity/Q490'), ('city', 'Milan'), ('nbpoets', '131')]
# [('birthplace', 'http://www.wikidata.org/entity/Q641'), ('city', 'Venice'), ('nbpoets', '93')]
# [('birthplace', 'http://www.wikidata.org/entity/Q1449'), ('city', 'Genoa'), ('nbpoets', '72')]
# [('birthplace', 'http://www.wikidata.org/entity/Q495'), ('city', 'Turin'), ('nbpoets', '60')]
# [('birthplace', 'http://www.wikidata.org/entity/Q546'), ('city', 'Trieste'), ('nbpoets', '59')]
# [('birthplace', 'http://www.wikidata.org/entity/Q1891'), ('city', 'Bologna'), ('nbpoets', '57')]
# [('birthplace', 'http://www.wikidata.org/entity/Q617'), ('city', 'Padua'), ('nbpoets', '49')]
# [('birthplace', 'http://www.wikidata.org/entity/Q2028'), ('city', 'Verona'), ('nbpoets', '44')]
# [('birthplace', 'http://www.wikidata.org/entity/Q2656'), ('city', 'Palermo'), ('nbpoets', '40')]
# [('birthplace', 'http://www.wikidata.org/entity/Q13362'), ('city', 'Ferrara'), ('nbpoets', '31')]
# [('birthplace', 'http://www.wikidata.org/entity/Q13666'), ('city', 'Messina'), ('nbpoets', '30')]
# [('birthplace', 'http://www.wikidata.org/entity/Q2751'), ('city', 'Siena'), ('nbpoets', '29')]
# [('birthplace', 'http://www.wikidata.org/entity/Q2683'), ('city', 'Parma'), ('nbpoets', '25')]
# [('birthplace', 'http://www.wikidata.org/entity/Q6537'), ('city', 'Vicenza'), ('nbpoets', '24')]
# [('birthplace', 'http://www.wikidata.org/entity/Q13373'), ('city', 'Lucca'), ('nbpoets', '24')]
# [('birthplace', 'http://www.wikidata.org/entity/Q1903'), ('city', 'Catania'), ('nbpoets', '24')]
# [('birthplace', 'http://www.wikidata.org/entity/Q279'), ('city', 'Modena'), ('nbpoets', '23')]
# 20

# %%
queryString = """
SELECT DISTINCT ?poet ?city ?educ
WHERE {
   # bind something
   # ?poet wdt:P106 wd:Q49757 ; #a poet
        wdt:P19 ?birthplace ;
        wdt:P69 ?university .
   # ?birthplace sc:name ?city ;
        wdt:P17 wd:Q38 .
   # ?university wdt:P131 ?educationcity .
   # ?educationcity sc:name ?educ .
   FILTER (?birthplace = ?educationcity)
} 
LIMIT 50 
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('poet', 'http://www.wikidata.org/entity/Q25106'), ('city', 'Genoa'), ('educ', 'Genoa')]
# [('poet', 'http://www.wikidata.org/entity/Q318309'), ('city', 'Bologna'), ('educ', 'Bologna')]
# [('poet', 'http://www.wikidata.org/entity/Q675583'), ('city', 'Rome'), ('educ', 'Rome')]
# [('poet', 'http://www.wikidata.org/entity/Q273334'), ('city', 'Naples'), ('educ', 'Naples')]
# [('poet', 'http://www.wikidata.org/entity/Q1130258'), ('city', 'Parma'), ('educ', 'Parma')]
# [('poet', 'http://www.wikidata.org/entity/Q535810'), ('city', 'Turin'), ('educ', 'Turin')]
# [('poet', 'http://www.wikidata.org/entity/Q659749'), ('city', 'Rome'), ('educ', 'Rome')]
# [('poet', 'http://www.wikidata.org/entity/Q153670'), ('city', 'Turin'), ('educ', 'Turin')]
# [('poet', 'http://www.wikidata.org/entity/Q733342'), ('city', 'Padua'), ('educ', 'Padua')]
# [('poet', 'http://www.wikidata.org/entity/Q919900'), ('city', 'Padua'), ('educ', 'Padua')]
# [('poet', 'http://www.wikidata.org/entity/Q350103'), ('city', 'Genoa'), ('educ', 'Genoa')]
# [('poet', 'http://www.wikidata.org/entity/Q1246391'), ('city', 'Urbino'), ('educ', 'Urbino')]
# [('poet', 'http://www.wikidata.org/entity/Q724672'), ('city', 'Ferrara'), ('educ', 'Ferrara')]
# [('poet', 'http://www.wikidata.org/entity/Q1227036'), ('city', 'Rome'), ('educ', 'Rome')]
# [('poet', 'http://www.wikidata.org/entity/Q354085'), ('city', 'Milan'), ('educ', 'Milan')]
# [('poet', 'http://www.wikidata.org/entity/Q3941603'), ('city', 'Turin'), ('educ', 'Turin')]
# [('poet', 'http://www.wikidata.org/entity/Q778716'), ('city', 'Turin'), ('educ', 'Turin')]
# [('poet', 'http://www.wikidata.org/entity/Q1131281'), ('city', 'Turin'), ('educ', 'Turin')]
# [('poet', 'http://www.wikidata.org/entity/Q25120'), ('city', 'Bologna'), ('educ', 'Bologna')]
# [('poet', 'http://www.wikidata.org/entity/Q1399'), ('city', 'Florence'), ('educ', 'Florence')]
# [('poet', 'http://www.wikidata.org/entity/Q3610195'), ('city', 'Florence'), ('educ', 'Florence')]
# [('poet', 'http://www.wikidata.org/entity/Q558128'), ('city', 'Rome'), ('educ', 'Rome')]
# [('poet', 'http://www.wikidata.org/entity/Q560126'), ('city', 'Rome'), ('educ', 'Rome')]
# [('poet', 'http://www.wikidata.org/entity/Q3659951'), ('city', 'Rome'), ('educ', 'Rome')]
# [('poet', 'http://www.wikidata.org/entity/Q507595'), ('city', 'Bari'), ('educ', 'Bari')]
# [('poet', 'http://www.wikidata.org/entity/Q3665362'), ('city', 'Milan'), ('educ', 'Milan')]
# [('poet', 'http://www.wikidata.org/entity/Q1439364'), ('city', 'Florence'), ('educ', 'Florence')]
# [('poet', 'http://www.wikidata.org/entity/Q16573950'), ('city', 'Rome'), ('educ', 'Rome')]
# [('poet', 'http://www.wikidata.org/entity/Q291866'), ('city', 'Rome'), ('educ', 'Rome')]
# [('poet', 'http://www.wikidata.org/entity/Q3852568'), ('city', 'Milan'), ('educ', 'Milan')]
# [('poet', 'http://www.wikidata.org/entity/Q3877170'), ('city', 'Turin'), ('educ', 'Turin')]
# [('poet', 'http://www.wikidata.org/entity/Q23017315'), ('city', 'Chieti'), ('educ', 'Chieti')]
# [('poet', 'http://www.wikidata.org/entity/Q334147'), ('city', 'Rome'), ('educ', 'Rome')]
# [('poet', 'http://www.wikidata.org/entity/Q867740'), ('city', 'Rome'), ('educ', 'Rome')]
# [('poet', 'http://www.wikidata.org/entity/Q366270'), ('city', 'Bologna'), ('educ', 'Bologna')]
# [('poet', 'http://www.wikidata.org/entity/Q52154284'), ('city', 'Naples'), ('educ', 'Naples')]
# [('poet', 'http://www.wikidata.org/entity/Q3724536'), ('city', 'Milan'), ('educ', 'Milan')]
# [('poet', 'http://www.wikidata.org/entity/Q272797'), ('city', 'Milan'), ('educ', 'Milan')]
# [('poet', 'http://www.wikidata.org/entity/Q2529303'), ('city', 'Turin'), ('educ', 'Turin')]
# [('poet', 'http://www.wikidata.org/entity/Q3107905'), ('city', 'Padua'), ('educ', 'Padua')]
# [('poet', 'http://www.wikidata.org/entity/Q3851007'), ('city', 'Florence'), ('educ', 'Florence')]
# [('poet', 'http://www.wikidata.org/entity/Q1246106'), ('city', 'Florence'), ('educ', 'Florence')]
# [('poet', 'http://www.wikidata.org/entity/Q1092012'), ('city', 'Milan'), ('educ', 'Milan')]
# [('poet', 'http://www.wikidata.org/entity/Q3838573'), ('city', 'Milan'), ('educ', 'Milan')]
# [('poet', 'http://www.wikidata.org/entity/Q378645'), ('city', 'Milan'), ('educ', 'Milan')]
# [('poet', 'http://www.wikidata.org/entity/Q1876253'), ('city', 'Milan'), ('educ', 'Milan')]
# [('poet', 'http://www.wikidata.org/entity/Q26649297'), ('city', 'Milan'), ('educ', 'Milan')]
# [('poet', 'http://www.wikidata.org/entity/Q89654187'), ('city', 'Milan'), ('educ', 'Milan')]
# [('poet', 'http://www.wikidata.org/entity/Q3106894'), ('city', 'Turin'), ('educ', 'Turin')]
# [('poet', 'http://www.wikidata.org/entity/Q3972451'), ('city', 'Padua'), ('educ', 'Padua')]
# 50

# %% [markdown]
# Final query for this task

# %%
# write your final query
queryString = """
SELECT DISTINCT ?city2 (COUNT(?poet2) as ?nbpoets) WHERE {
    # ?poet2 wdt:P106 wd:Q49757 ; #a poet
            wdt:P19 ?birthplace2 .
    # ?birthplace2 sc:name ?city2 .       
    
    {
        SELECT DISTINCT ?poet ?city
        WHERE {
           # bind something
           # ?poet wdt:P106 wd:Q49757 ; #a poet
                wdt:P19 ?birthplace ;
                wdt:P69 ?university .
           # ?birthplace sc:name ?city ;
                wdt:P17 wd:Q38 .
           # ?university wdt:P131 ?educationcity .
           FILTER (?birthplace = ?educationcity)
        } 
    }
    FILTER (?poet2 = ?poet)
} GROUP BY ?city2
ORDER BY DESC(?nbpoets)
LIMIT 20 
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('city2', 'Rome'), ('nbpoets', '16')]
# [('city2', 'Milan'), ('nbpoets', '14')]
# [('city2', 'Florence'), ('nbpoets', '9')]
# [('city2', 'Turin'), ('nbpoets', '9')]
# [('city2', 'Padua'), ('nbpoets', '4')]
# [('city2', 'Bologna'), ('nbpoets', '4')]
# [('city2', 'Genoa'), ('nbpoets', '3')]
# [('city2', 'Trieste'), ('nbpoets', '2')]
# [('city2', 'Parma'), ('nbpoets', '2')]
# [('city2', 'Naples'), ('nbpoets', '2')]
# [('city2', 'Urbino'), ('nbpoets', '2')]
# [('city2', 'Ferrara'), ('nbpoets', '1')]
# [('city2', 'Terlizzi'), ('nbpoets', '1')]
# [('city2', 'Catania'), ('nbpoets', '1')]
# [('city2', 'Bari'), ('nbpoets', '1')]
# [('city2', 'Siena'), ('nbpoets', '1')]
# [('city2', 'Sassari'), ('nbpoets', '1')]
# [('city2', 'Messina'), ('nbpoets', '1')]
# [('city2', 'Chieti'), ('nbpoets', '1')]
# [('city2', 'Prato'), ('nbpoets', '1')]
# 20

# %% [markdown]
# ## Task 8
# Return the italian poets who won the Nobel Prize in Literature (the result set must be poet IRI and label).

# %%
# write your queries
# As the Nobel Prize of Literature is something given to writers(I think) we're retrieving the properties of writer
# results not very relevant
queryString = """
SELECT DISTINCT ?p ?namep ?o ?name  
WHERE {
   # bind something
   wd:Q36180 ?p ?o .
    # ?p sc:name ?namep .
   # ?o sc:name ?name .
} 
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P425'), ('namep', 'field of this occupation'), ('o', 'http://www.wikidata.org/entity/Q37260'), ('name', 'writing')]
# [('p', 'http://www.wikidata.org/prop/direct/P425'), ('namep', 'field of this occupation'), ('o', 'http://www.wikidata.org/entity/Q2250012'), ('name', 'writing')]
# [('p', 'http://www.wikidata.org/prop/direct/P910'), ('namep', "topic's main category"), ('o', 'http://www.wikidata.org/entity/Q5849863'), ('name', 'Category:Writers')]
# [('p', 'http://www.wikidata.org/prop/direct/P1687'), ('namep', 'Wikidata property'), ('o', 'http://www.wikidata.org/entity/P50'), ('name', 'author')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('namep', 'instance of'), ('o', 'http://www.wikidata.org/entity/Q12737077'), ('name', 'occupation')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('namep', 'instance of'), ('o', 'http://www.wikidata.org/entity/Q28640'), ('name', 'profession')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('namep', 'instance of'), ('o', 'http://www.wikidata.org/entity/Q4164871'), ('name', 'position')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('namep', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q482980'), ('name', 'author')]
# [('p', 'http://www.wikidata.org/prop/direct/P5008'), ('namep', 'on focus list of Wikimedia project'), ('o', 'http://www.wikidata.org/entity/Q98970039'), ('name', 'WikiProject PCC Wikidata Pilot/University of Washington')]
# [('p', 'http://www.wikidata.org/prop/direct/P2354'), ('namep', 'has list'), ('o', 'http://www.wikidata.org/entity/Q13019738'), ('name', 'list of lists of writers')]
# [('p', 'http://www.wikidata.org/prop/direct/P6186'), ('namep', 'category for eponymous categories'), ('o', 'http://www.wikidata.org/entity/Q6963972'), ('name', 'Category:Wikipedia categories named after writers')]
# [('p', 'http://www.wikidata.org/prop/direct/P1687'), ('namep', 'Wikidata property'), ('o', 'http://www.wikidata.org/entity/P2093'), ('name', 'author name string')]
# [('p', 'http://www.wikidata.org/prop/direct/P1424'), ('namep', "topic's main template"), ('o', 'http://www.wikidata.org/entity/Q5615832'), ('name', 'Template:Infobox writer')]
# [('p', 'http://www.wikidata.org/prop/direct/P1424'), ('namep', "topic's main template"), ('o', 'http://www.wikidata.org/entity/Q6535605'), ('name', 'Template:Writer-stub')]
# 14

# %%
# we have a property Significant Person, maybe we can use it. First we'll try to see what there is in it
queryString = """
SELECT DISTINCT ?s ?nameS ?o ?name  
WHERE {
   # bind something
   # ?s wdt:P3342 ?o .
    # ?s sc:name ?nameS .
   # ?o sc:name ?name .
} 
LIMIT 50
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('s', 'http://www.wikidata.org/entity/Q15734590'), ('nameS', 'Alma Sundquist'), ('o', 'http://www.wikidata.org/entity/Q15734554'), ('name', 'Thora Wigardh')]
# [('s', 'http://www.wikidata.org/entity/Q4969542'), ('nameS', 'Ada Nilsson'), ('o', 'http://www.wikidata.org/entity/Q15734554'), ('name', 'Thora Wigardh')]
# [('s', 'http://www.wikidata.org/entity/Q4767613'), ('nameS', 'Anna Whitlock'), ('o', 'http://www.wikidata.org/entity/Q15734554'), ('name', 'Thora Wigardh')]
# [('s', 'http://www.wikidata.org/entity/Q4990100'), ('nameS', 'Lydia Wahlström'), ('o', 'http://www.wikidata.org/entity/Q15734554'), ('name', 'Thora Wigardh')]
# [('s', 'http://www.wikidata.org/entity/Q106903887'), ('nameS', 'Petroccelli'), ('o', 'http://www.wikidata.org/entity/Q16059906'), ('name', 'Vincenzo Petroccelli')]
# [('s', 'http://www.wikidata.org/entity/Q485664'), ('nameS', 'Sukjong of Joseon'), ('o', 'http://www.wikidata.org/entity/Q16184469'), ('name', 'Nam Gu-man')]
# [('s', 'http://www.wikidata.org/entity/Q466623'), ('nameS', 'Elsa Beskow'), ('o', 'http://www.wikidata.org/entity/Q462879'), ('name', 'Alice Tegnér')]
# [('s', 'http://www.wikidata.org/entity/Q4990938'), ('nameS', 'Lilli Zickerman'), ('o', 'http://www.wikidata.org/entity/Q17493718'), ('name', 'Anna Wettergren-Behm')]
# [('s', 'http://www.wikidata.org/entity/Q1611548'), ('nameS', 'Hermann Huber'), ('o', 'http://www.wikidata.org/entity/Q214564'), ('name', 'Ferdinand Hodler')]
# [('s', 'http://www.wikidata.org/entity/Q2023784'), ('nameS', 'Hooge Crater Cemetery'), ('o', 'http://www.wikidata.org/entity/Q21664044'), ('name', 'Albert Stewart')]
# [('s', 'http://www.wikidata.org/entity/Q370217'), ('nameS', 'Dustin Moskovitz'), ('o', 'http://www.wikidata.org/entity/Q36215'), ('name', 'Mark Zuckerberg')]
# [('s', 'http://www.wikidata.org/entity/Q3320915'), ('nameS', 'David Bravo Bueno'), ('o', 'http://www.wikidata.org/entity/Q21936906'), ('name', 'Wismichu')]
# [('s', 'http://www.wikidata.org/entity/Q21936906'), ('nameS', 'Wismichu'), ('o', 'http://www.wikidata.org/entity/Q3320915'), ('name', 'David Bravo Bueno')]
# [('s', 'http://www.wikidata.org/entity/Q21936906'), ('nameS', 'Wismichu'), ('o', 'http://www.wikidata.org/entity/Q59514029'), ('name', 'Dalas Review')]
# [('s', 'http://www.wikidata.org/entity/Q2433150'), ('nameS', '1983 NASCAR Winston Cup Series'), ('o', 'http://www.wikidata.org/entity/Q2061570'), ('name', 'Sterling Marlin')]
# [('s', 'http://www.wikidata.org/entity/Q127434'), ('nameS', '2005 NHL Entry Draft'), ('o', 'http://www.wikidata.org/entity/Q311280'), ('name', 'Sidney Crosby')]
# [('s', 'http://www.wikidata.org/entity/Q6034'), ('nameS', 'Dada'), ('o', 'http://www.wikidata.org/entity/Q463411'), ('name', 'Hannah Höch')]
# [('s', 'http://www.wikidata.org/entity/Q67815'), ('nameS', 'Helmina von Chézy'), ('o', 'http://www.wikidata.org/entity/Q468618'), ('name', 'Dominique Vivant')]
# [('s', 'http://www.wikidata.org/entity/Q160202'), ('nameS', 'Franz Anton Mesmer'), ('o', 'http://www.wikidata.org/entity/Q26246856'), ('name', 'Franziska von Posch')]
# [('s', 'http://www.wikidata.org/entity/Q26832770'), ('nameS', 'Galerie Chirvan'), ('o', 'http://www.wikidata.org/entity/Q16524645'), ('name', 'Adriano Gajoni')]
# [('s', 'http://www.wikidata.org/entity/Q1611548'), ('nameS', 'Hermann Huber'), ('o', 'http://www.wikidata.org/entity/Q15807329'), ('name', 'Eduard Bick')]
# [('s', 'http://www.wikidata.org/entity/Q1611548'), ('nameS', 'Hermann Huber'), ('o', 'http://www.wikidata.org/entity/Q27229278'), ('name', 'Thomas Ernst Gubler')]
# [('s', 'http://www.wikidata.org/entity/Q30243280'), ('nameS', 'Bonadea'), ('o', 'http://www.wikidata.org/entity/Q30106696'), ('name', 'Ulrich')]
# [('s', 'http://www.wikidata.org/entity/Q30243389'), ('nameS', 'Clarisse'), ('o', 'http://www.wikidata.org/entity/Q30106696'), ('name', 'Ulrich')]
# [('s', 'http://www.wikidata.org/entity/Q30243402'), ('nameS', 'Walter'), ('o', 'http://www.wikidata.org/entity/Q30106696'), ('name', 'Ulrich')]
# [('s', 'http://www.wikidata.org/entity/Q30243528'), ('nameS', 'Paul Arnheim'), ('o', 'http://www.wikidata.org/entity/Q30106696'), ('name', 'Ulrich')]
# [('s', 'http://www.wikidata.org/entity/Q30250689'), ('nameS', 'Gerda Fischel'), ('o', 'http://www.wikidata.org/entity/Q30106696'), ('name', 'Ulrich')]
# [('s', 'http://www.wikidata.org/entity/Q30106696'), ('nameS', 'Ulrich'), ('o', 'http://www.wikidata.org/entity/Q30243280'), ('name', 'Bonadea')]
# [('s', 'http://www.wikidata.org/entity/Q30243528'), ('nameS', 'Paul Arnheim'), ('o', 'http://www.wikidata.org/entity/Q30243330'), ('name', 'Diotima')]
# [('s', 'http://www.wikidata.org/entity/Q30250839'), ('nameS', 'Count Leinsdorf'), ('o', 'http://www.wikidata.org/entity/Q30243330'), ('name', 'Diotima')]
# [('s', 'http://www.wikidata.org/entity/Q1501666'), ('nameS', 'General Stumm von Bordwehr'), ('o', 'http://www.wikidata.org/entity/Q30243330'), ('name', 'Diotima')]
# [('s', 'http://www.wikidata.org/entity/Q30106696'), ('nameS', 'Ulrich'), ('o', 'http://www.wikidata.org/entity/Q30243389'), ('name', 'Clarisse')]
# [('s', 'http://www.wikidata.org/entity/Q30106696'), ('nameS', 'Ulrich'), ('o', 'http://www.wikidata.org/entity/Q30243402'), ('name', 'Walter')]
# [('s', 'http://www.wikidata.org/entity/Q30106696'), ('nameS', 'Ulrich'), ('o', 'http://www.wikidata.org/entity/Q30243528'), ('name', 'Paul Arnheim')]
# [('s', 'http://www.wikidata.org/entity/Q30243330'), ('nameS', 'Diotima'), ('o', 'http://www.wikidata.org/entity/Q30243528'), ('name', 'Paul Arnheim')]
# [('s', 'http://www.wikidata.org/entity/Q30106696'), ('nameS', 'Ulrich'), ('o', 'http://www.wikidata.org/entity/Q30250689'), ('name', 'Gerda Fischel')]
# [('s', 'http://www.wikidata.org/entity/Q30243330'), ('nameS', 'Diotima'), ('o', 'http://www.wikidata.org/entity/Q30250839'), ('name', 'Count Leinsdorf')]
# [('s', 'http://www.wikidata.org/entity/Q91336419'), ('nameS', 'Tommy Merlyn'), ('o', 'http://www.wikidata.org/entity/Q19866576'), ('name', 'Oliver Queen')]
# [('s', 'http://www.wikidata.org/entity/Q19866576'), ('nameS', 'Oliver Queen'), ('o', 'http://www.wikidata.org/entity/Q91336419'), ('name', 'Tommy Merlyn')]
# [('s', 'http://www.wikidata.org/entity/Q30652305'), ('nameS', 'Cage of la Corriveau'), ('o', 'http://www.wikidata.org/entity/Q3291969'), ('name', 'Marie-Josephte Corriveau')]
# [('s', 'http://www.wikidata.org/entity/Q2758129'), ('nameS', 'Helena Harper'), ('o', 'http://www.wikidata.org/entity/Q16565826'), ('name', 'Ingrid Hunnigan')]
# [('s', 'http://www.wikidata.org/entity/Q1138965'), ('nameS', 'Leon Scott Kennedy'), ('o', 'http://www.wikidata.org/entity/Q16565826'), ('name', 'Ingrid Hunnigan')]
# [('s', 'http://www.wikidata.org/entity/Q16565826'), ('nameS', 'Ingrid Hunnigan'), ('o', 'http://www.wikidata.org/entity/Q2758129'), ('name', 'Helena Harper')]
# [('s', 'http://www.wikidata.org/entity/Q1138965'), ('nameS', 'Leon Scott Kennedy'), ('o', 'http://www.wikidata.org/entity/Q2758129'), ('name', 'Helena Harper')]
# [('s', 'http://www.wikidata.org/entity/Q104450705'), ('nameS', 'Processo do padre António Vieira'), ('o', 'http://www.wikidata.org/entity/Q458650'), ('name', 'António Vieira')]
# [('s', 'http://www.wikidata.org/entity/Q8134'), ('nameS', 'economics'), ('o', 'http://www.wikidata.org/entity/Q9317'), ('name', 'John Maynard Keynes')]
# [('s', 'http://www.wikidata.org/entity/Q11634'), ('nameS', 'art of sculpture'), ('o', 'http://www.wikidata.org/entity/Q1122412'), ('name', 'Giannino Castiglioni')]
# [('s', 'http://www.wikidata.org/entity/Q485009'), ('nameS', 'Yeongjo of Joseon'), ('o', 'http://www.wikidata.org/entity/Q12588940'), ('name', 'Kim Chang-jip')]
# [('s', 'http://www.wikidata.org/entity/Q485009'), ('nameS', 'Yeongjo of Joseon'), ('o', 'http://www.wikidata.org/entity/Q12596325'), ('name', 'Min Jin-won')]
# [('s', 'http://www.wikidata.org/entity/Q485009'), ('nameS', 'Yeongjo of Joseon'), ('o', 'http://www.wikidata.org/entity/Q16178177'), ('name', 'Kim Jae-ro')]
# 50

# %%
# It's strange. For Keynes for example, it seems that the object of Significant person is a person and the subject, the reason why. But it doesn't seem the case most of the time.
# We'll try to put the object as a writer, we'll see what we can obtain
queryString = """
SELECT DISTINCT ?s ?nameS
WHERE {
   # bind something
   # ?writer wdt:P106 wd:Q36180 .
   # ?s wdt:P3342 ?writer ;
       sc:name ?nameS .
} 
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('s', 'http://www.wikidata.org/entity/Q21936906'), ('nameS', 'Wismichu')]
# [('s', 'http://www.wikidata.org/entity/Q468618'), ('nameS', 'Dominique Vivant')]
# [('s', 'http://www.wikidata.org/entity/Q104450705'), ('nameS', 'Processo do padre António Vieira')]
# [('s', 'http://www.wikidata.org/entity/Q958683'), ('nameS', 'Nick Kamen')]
# [('s', 'http://www.wikidata.org/entity/Q2642427'), ('nameS', 'Albert Engström')]
# [('s', 'http://www.wikidata.org/entity/Q48235'), ('nameS', 'stoicism')]
# [('s', 'http://www.wikidata.org/entity/Q485009'), ('nameS', 'Yeongjo of Joseon')]
# [('s', 'http://www.wikidata.org/entity/Q77079'), ('nameS', 'Jean Paul')]
# [('s', 'http://www.wikidata.org/entity/Q4988547'), ('nameS', 'Ida Gawell-Blumenthal')]
# [('s', 'http://www.wikidata.org/entity/Q549109'), ('nameS', 'Artur Hazelius')]
# [('s', 'http://www.wikidata.org/entity/Q552288'), ('nameS', 'R. H. Barlow')]
# [('s', 'http://www.wikidata.org/entity/Q57074'), ('nameS', 'Nelly Sachs')]
# [('s', 'http://www.wikidata.org/entity/Q3816'), ('nameS', 'George Sand')]
# [('s', 'http://www.wikidata.org/entity/Q3296046'), ('nameS', 'Marvel Productions')]
# [('s', 'http://www.wikidata.org/entity/Q380937'), ('nameS', 'Erik Gustaf Geijer')]
# [('s', 'http://www.wikidata.org/entity/Q55037230'), ('nameS', 'Stéphanie Félicité Ducrest de Saint-Aubin de Genlis')]
# [('s', 'http://www.wikidata.org/entity/Q243068'), ('nameS', 'Anne Charlotte Leffler')]
# [('s', 'http://www.wikidata.org/entity/Q4939281'), ('nameS', 'Olga Björkegren')]
# [('s', 'http://www.wikidata.org/entity/Q4967393'), ('nameS', 'Ruth Milles')]
# [('s', 'http://www.wikidata.org/entity/Q469339'), ('nameS', 'Alfhild Agrell')]
# [('s', 'http://www.wikidata.org/entity/Q215691'), ('nameS', 'Karl August Varnhagen von Ense')]
# [('s', 'http://www.wikidata.org/entity/Q29324277'), ('nameS', 'tomb of Garsenda of Sabran, comtesse of Forcalquier')]
# [('s', 'http://www.wikidata.org/entity/Q184535'), ('nameS', 'Sofia Kovalevskaya')]
# [('s', 'http://www.wikidata.org/entity/Q39427'), ('nameS', 'surrealism')]
# [('s', 'http://www.wikidata.org/entity/Q48589'), ('nameS', 'Zenta Mauriņa')]
# [('s', 'http://www.wikidata.org/entity/Q58586'), ('nameS', 'Edmund Husserl')]
# [('s', 'http://www.wikidata.org/entity/Q94514551'), ('nameS', 'Else Seel')]
# [('s', 'http://www.wikidata.org/entity/Q89625'), ('nameS', 'Ludwig von Ficker')]
# [('s', 'http://www.wikidata.org/entity/Q163366'), ('nameS', 'Ezra Pound')]
# [('s', 'http://www.wikidata.org/entity/Q172684'), ('nameS', 'Aleister Crowley')]
# [('s', 'http://www.wikidata.org/entity/Q25107'), ('nameS', 'power')]
# [('s', 'http://www.wikidata.org/entity/Q5062902'), ('nameS', 'The Lee Strasberg Theatre Institute')]
# [('s', 'http://www.wikidata.org/entity/Q93210691'), ('nameS', 'Sydna Edmonia Robella Francis')]
# [('s', 'http://www.wikidata.org/entity/Q15734590'), ('nameS', 'Alma Sundquist')]
# [('s', 'http://www.wikidata.org/entity/Q238443'), ('nameS', 'Ellen Key')]
# [('s', 'http://www.wikidata.org/entity/Q270468'), ('nameS', 'Elin Wägner')]
# [('s', 'http://www.wikidata.org/entity/Q4568363'), ('nameS', 'Barbro Alving')]
# [('s', 'http://www.wikidata.org/entity/Q4940406'), ('nameS', 'Elin Brandell')]
# [('s', 'http://www.wikidata.org/entity/Q4948398'), ('nameS', 'Emilia Fogelklou')]
# [('s', 'http://www.wikidata.org/entity/Q4953745'), ('nameS', 'Honorine Hermelin')]
# [('s', 'http://www.wikidata.org/entity/Q4953847'), ('nameS', 'Kerstin Hesselgren')]
# [('s', 'http://www.wikidata.org/entity/Q4954629'), ('nameS', 'Britta Holmström')]
# [('s', 'http://www.wikidata.org/entity/Q4969542'), ('nameS', 'Ada Nilsson')]
# [('s', 'http://www.wikidata.org/entity/Q4976087'), ('nameS', 'Ellen Rydelius')]
# [('s', 'http://www.wikidata.org/entity/Q4980157'), ('nameS', 'Frida Stéenhoff')]
# [('s', 'http://www.wikidata.org/entity/Q4981979'), ('nameS', 'Elisabeth Tamm')]
# [('s', 'http://www.wikidata.org/entity/Q50803162'), ('nameS', 'Flory Gate')]
# [('s', 'http://www.wikidata.org/entity/Q50809185'), ('nameS', 'Ellen Landquist')]
# [('s', 'http://www.wikidata.org/entity/Q50926751'), ('nameS', 'Klara Lindh')]
# [('s', 'http://www.wikidata.org/entity/Q1500'), ('nameS', 'José Rizal')]
# [('s', 'http://www.wikidata.org/entity/Q1611548'), ('nameS', 'Hermann Huber')]
# [('s', 'http://www.wikidata.org/entity/Q312542'), ('nameS', 'Marcelo H. del Pilar')]
# [('s', 'http://www.wikidata.org/entity/Q4970016'), ('nameS', 'Alice Nordin')]
# [('s', 'http://www.wikidata.org/entity/Q27841'), ('nameS', 'economic anthropology')]
# [('s', 'http://www.wikidata.org/entity/Q4766181'), ('nameS', 'Ann-Margret Holmgren')]
# [('s', 'http://www.wikidata.org/entity/Q431143'), ('nameS', 'Božena Benešová')]
# [('s', 'http://www.wikidata.org/entity/Q434056'), ('nameS', 'Anna Branting')]
# [('s', 'http://www.wikidata.org/entity/Q4953125'), ('nameS', 'Alma Hedin')]
# [('s', 'http://www.wikidata.org/entity/Q4976841'), ('nameS', 'Maria Sandel')]
# [('s', 'http://www.wikidata.org/entity/Q53620'), ('nameS', 'Hjalmar Branting')]
# [('s', 'http://www.wikidata.org/entity/Q462363'), ('nameS', 'Helen Hunt Jackson')]
# [('s', 'http://www.wikidata.org/entity/Q51800428'), ('nameS', 'Mathilde Wigert-Österlund')]
# [('s', 'http://www.wikidata.org/entity/Q484359'), ('nameS', 'Seonjo of Joseon')]
# [('s', 'http://www.wikidata.org/entity/Q262145'), ('nameS', 'Fredrika Bremer')]
# [('s', 'http://www.wikidata.org/entity/Q157271'), ('nameS', 'Friedrich Schlegel')]
# [('s', 'http://www.wikidata.org/entity/Q3172270'), ('nameS', 'Johann Gottfried Schweighäuser')]
# [('s', 'http://www.wikidata.org/entity/Q3181548'), ('nameS', 'Kutsuki Masatsuna')]
# [('s', 'http://www.wikidata.org/entity/Q67815'), ('nameS', 'Helmina von Chézy')]
# [('s', 'http://www.wikidata.org/entity/Q77271'), ('nameS', 'Dorothea von Schlegel')]
# [('s', 'http://www.wikidata.org/entity/Q5164922'), ('nameS', 'Contax I')]
# [('s', 'http://www.wikidata.org/entity/Q5169832'), ('nameS', 'Corcadorca Theatre Company')]
# [('s', 'http://www.wikidata.org/entity/Q4959294'), ('nameS', 'Thekla Knös')]
# [('s', 'http://www.wikidata.org/entity/Q3992'), ('nameS', 'Liège')]
# [('s', 'http://www.wikidata.org/entity/Q7197'), ('nameS', 'Simone de Beauvoir')]
# [('s', 'http://www.wikidata.org/entity/Q8134'), ('nameS', 'economics')]
# [('s', 'http://www.wikidata.org/entity/Q9364'), ('nameS', 'Jean-Paul Sartre')]
# [('s', 'http://www.wikidata.org/entity/Q6504956'), ('nameS', 'data visualization')]
# [('s', 'http://www.wikidata.org/entity/Q707629'), ('nameS', 'Northeast Anti-Japanese United Army')]
# [('s', 'http://www.wikidata.org/entity/Q2002653'), ('nameS', 'amor fati')]
# [('s', 'http://www.wikidata.org/entity/Q4410099'), ('nameS', 'Dmitry Sverbeyev')]
# [('s', 'http://www.wikidata.org/entity/Q23988983'), ('nameS', 'Eva Upmark')]
# [('s', 'http://www.wikidata.org/entity/Q466623'), ('nameS', 'Elsa Beskow')]
# [('s', 'http://www.wikidata.org/entity/Q4767613'), ('nameS', 'Anna Whitlock')]
# [('s', 'http://www.wikidata.org/entity/Q4937621'), ('nameS', 'Signe Barth')]
# [('s', 'http://www.wikidata.org/entity/Q4953755'), ('nameS', 'Elisabet Hermodsson')]
# [('s', 'http://www.wikidata.org/entity/Q546949'), ('nameS', 'Malla Silfverstolpe')]
# [('s', 'http://www.wikidata.org/entity/Q63247022'), ('nameS', 'Margareta Beckius')]
# [('s', 'http://www.wikidata.org/entity/Q71259399'), ('nameS', 'Anna Lisa Rolf')]
# [('s', 'http://www.wikidata.org/entity/Q99776118'), ('nameS', 'Wilhelmina Natalia Palmaer')]
# [('s', 'http://www.wikidata.org/entity/Q154812'), ('nameS', 'Carl Maria von Weber')]
# [('s', 'http://www.wikidata.org/entity/Q6034'), ('nameS', 'Dada')]
# [('s', 'http://www.wikidata.org/entity/Q61793'), ('nameS', 'Rahel Varnhagen')]
# [('s', 'http://www.wikidata.org/entity/Q1631'), ('nameS', 'Édith Piaf')]
# [('s', 'http://www.wikidata.org/entity/Q152437'), ('nameS', 'Alva Myrdal')]
# [('s', 'http://www.wikidata.org/entity/Q365858'), ('nameS', 'Knut Wicksell')]
# [('s', 'http://www.wikidata.org/entity/Q828580'), ('nameS', 'Jack Garfein')]
# [('s', 'http://www.wikidata.org/entity/Q1118654'), ('nameS', 'institutional economics')]
# [('s', 'http://www.wikidata.org/entity/Q193959'), ('nameS', 'marketing mix')]
# [('s', 'http://www.wikidata.org/entity/Q44403'), ('nameS', 'Heinrich Heine')]
# [('s', 'http://www.wikidata.org/entity/Q160202'), ('nameS', 'Franz Anton Mesmer')]
# 100

# %%
# It seems that we have also painters and economists in the list. Maybe we can reduce with poets.
queryString = """
SELECT DISTINCT ?s ?names
WHERE {
   # bind something
   # ?poet wdt:P106 wd:Q49757 .
   # ?s wdt:P3342 ?poet ;
       sc:name ?names .
} 
LIMIT 50
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('s', 'http://www.wikidata.org/entity/Q468618'), ('names', 'Dominique Vivant')]
# [('s', 'http://www.wikidata.org/entity/Q63213350'), ('names', 'Sentiero di Leonardo da Vinci')]
# [('s', 'http://www.wikidata.org/entity/Q958683'), ('names', 'Nick Kamen')]
# [('s', 'http://www.wikidata.org/entity/Q77079'), ('names', 'Jean Paul')]
# [('s', 'http://www.wikidata.org/entity/Q108427348'), ('names', "Marie-Marguerite d'Alègre")]
# [('s', 'http://www.wikidata.org/entity/Q4988547'), ('names', 'Ida Gawell-Blumenthal')]
# [('s', 'http://www.wikidata.org/entity/Q552288'), ('names', 'R. H. Barlow')]
# [('s', 'http://www.wikidata.org/entity/Q57074'), ('names', 'Nelly Sachs')]
# [('s', 'http://www.wikidata.org/entity/Q3816'), ('names', 'George Sand')]
# [('s', 'http://www.wikidata.org/entity/Q738671'), ('names', 'Val Bregaglia')]
# [('s', 'http://www.wikidata.org/entity/Q55037230'), ('names', 'Stéphanie Félicité Ducrest de Saint-Aubin de Genlis')]
# [('s', 'http://www.wikidata.org/entity/Q243068'), ('names', 'Anne Charlotte Leffler')]
# [('s', 'http://www.wikidata.org/entity/Q215691'), ('names', 'Karl August Varnhagen von Ense')]
# [('s', 'http://www.wikidata.org/entity/Q29324277'), ('names', 'tomb of Garsenda of Sabran, comtesse of Forcalquier')]
# [('s', 'http://www.wikidata.org/entity/Q39427'), ('names', 'surrealism')]
# [('s', 'http://www.wikidata.org/entity/Q48589'), ('names', 'Zenta Mauriņa')]
# [('s', 'http://www.wikidata.org/entity/Q94514551'), ('names', 'Else Seel')]
# [('s', 'http://www.wikidata.org/entity/Q89625'), ('names', 'Ludwig von Ficker')]
# [('s', 'http://www.wikidata.org/entity/Q163366'), ('names', 'Ezra Pound')]
# [('s', 'http://www.wikidata.org/entity/Q172684'), ('names', 'Aleister Crowley')]
# [('s', 'http://www.wikidata.org/entity/Q25107'), ('names', 'power')]
# [('s', 'http://www.wikidata.org/entity/Q1611548'), ('names', 'Hermann Huber')]
# [('s', 'http://www.wikidata.org/entity/Q312542'), ('names', 'Marcelo H. del Pilar')]
# [('s', 'http://www.wikidata.org/entity/Q462363'), ('names', 'Helen Hunt Jackson')]
# [('s', 'http://www.wikidata.org/entity/Q484359'), ('names', 'Seonjo of Joseon')]
# [('s', 'http://www.wikidata.org/entity/Q157271'), ('names', 'Friedrich Schlegel')]
# [('s', 'http://www.wikidata.org/entity/Q3172270'), ('names', 'Johann Gottfried Schweighäuser')]
# [('s', 'http://www.wikidata.org/entity/Q67815'), ('names', 'Helmina von Chézy')]
# [('s', 'http://www.wikidata.org/entity/Q77271'), ('names', 'Dorothea von Schlegel')]
# [('s', 'http://www.wikidata.org/entity/Q4959294'), ('names', 'Thekla Knös')]
# [('s', 'http://www.wikidata.org/entity/Q8134'), ('names', 'economics')]
# [('s', 'http://www.wikidata.org/entity/Q3485863'), ('names', 'Siege of Constantinople')]
# [('s', 'http://www.wikidata.org/entity/Q15581'), ('names', 'Principality of Catalonia')]
# [('s', 'http://www.wikidata.org/entity/Q2002653'), ('names', 'amor fati')]
# [('s', 'http://www.wikidata.org/entity/Q4410099'), ('names', 'Dmitry Sverbeyev')]
# [('s', 'http://www.wikidata.org/entity/Q466623'), ('names', 'Elsa Beskow')]
# [('s', 'http://www.wikidata.org/entity/Q546949'), ('names', 'Malla Silfverstolpe')]
# [('s', 'http://www.wikidata.org/entity/Q6577515'), ('names', 'Samuel')]
# [('s', 'http://www.wikidata.org/entity/Q90838008'), ('names', 'Armenian Relief Committee - French section')]
# [('s', 'http://www.wikidata.org/entity/Q334308'), ('names', 'Sejo of Joseon')]
# [('s', 'http://www.wikidata.org/entity/Q42935'), ('names', 'Mandello del Lario')]
# [('s', 'http://www.wikidata.org/entity/Q6237'), ('names', 'Lecco')]
# [('s', 'http://www.wikidata.org/entity/Q154812'), ('names', 'Carl Maria von Weber')]
# [('s', 'http://www.wikidata.org/entity/Q6034'), ('names', 'Dada')]
# [('s', 'http://www.wikidata.org/entity/Q61793'), ('names', 'Rahel Varnhagen')]
# [('s', 'http://www.wikidata.org/entity/Q1631'), ('names', 'Édith Piaf')]
# [('s', 'http://www.wikidata.org/entity/Q828580'), ('names', 'Jack Garfein')]
# [('s', 'http://www.wikidata.org/entity/Q44403'), ('names', 'Heinrich Heine')]
# [('s', 'http://www.wikidata.org/entity/Q813280'), ('names', 'Beatrice d’Este')]
# [('s', 'http://www.wikidata.org/entity/Q35548'), ('names', 'Paul Cézanne')]
# 50

# %%
# Don't know if it's cheating but doing the NBA workflow we found the property award received by retrieving the properties of France
#So we're gonna try to find again this property with what we have there, Italy
queryString = """
SELECT DISTINCT ?p ?name 
WHERE {
   # bind something
   wd:Q38 ?p ?o .
   # ?p sc:name ?name .
   FILTER (!isLiteral(?o)).
} 
LIMIT 40
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P1151'), ('name', "topic's main Wikimedia portal")]
# [('p', 'http://www.wikidata.org/prop/direct/P122'), ('name', 'basic form of government')]
# [('p', 'http://www.wikidata.org/prop/direct/P1313'), ('name', 'office held by head of government')]
# [('p', 'http://www.wikidata.org/prop/direct/P1343'), ('name', 'described by source')]
# [('p', 'http://www.wikidata.org/prop/direct/P1365'), ('name', 'replaces')]
# [('p', 'http://www.wikidata.org/prop/direct/P1419'), ('name', 'shape')]
# [('p', 'http://www.wikidata.org/prop/direct/P1464'), ('name', 'category for people born here')]
# [('p', 'http://www.wikidata.org/prop/direct/P1465'), ('name', 'category for people who died here')]
# [('p', 'http://www.wikidata.org/prop/direct/P150'), ('name', 'contains administrative territorial entity')]
# [('p', 'http://www.wikidata.org/prop/direct/P155'), ('name', 'follows')]
# [('p', 'http://www.wikidata.org/prop/direct/P1552'), ('name', 'has quality')]
# [('p', 'http://www.wikidata.org/prop/direct/P1589'), ('name', 'lowest point')]
# [('p', 'http://www.wikidata.org/prop/direct/P1622'), ('name', 'driving side')]
# [('p', 'http://www.wikidata.org/prop/direct/P163'), ('name', 'flag')]
# [('p', 'http://www.wikidata.org/prop/direct/P17'), ('name', 'country')]
# [('p', 'http://www.wikidata.org/prop/direct/P1740'), ('name', 'category for films shot at this location')]
# [('p', 'http://www.wikidata.org/prop/direct/P1791'), ('name', 'category of people buried here')]
# [('p', 'http://www.wikidata.org/prop/direct/P1792'), ('name', 'category of associated people')]
# [('p', 'http://www.wikidata.org/prop/direct/P1906'), ('name', 'office held by head of state')]
# [('p', 'http://www.wikidata.org/prop/direct/P194'), ('name', 'legislative body')]
# [('p', 'http://www.wikidata.org/prop/direct/P206'), ('name', 'located in or next to body of water')]
# [('p', 'http://www.wikidata.org/prop/direct/P208'), ('name', 'executive body')]
# [('p', 'http://www.wikidata.org/prop/direct/P209'), ('name', 'highest judicial authority')]
# [('p', 'http://www.wikidata.org/prop/direct/P2184'), ('name', 'history of topic')]
# [('p', 'http://www.wikidata.org/prop/direct/P237'), ('name', 'coat of arms')]
# [('p', 'http://www.wikidata.org/prop/direct/P242'), ('name', 'locator map image')]
# [('p', 'http://www.wikidata.org/prop/direct/P2596'), ('name', 'culture')]
# [('p', 'http://www.wikidata.org/prop/direct/P2633'), ('name', 'geography of topic')]
# [('p', 'http://www.wikidata.org/prop/direct/P2852'), ('name', 'emergency telephone number')]
# [('p', 'http://www.wikidata.org/prop/direct/P2853'), ('name', 'electrical plug type')]
# [('p', 'http://www.wikidata.org/prop/direct/P2936'), ('name', 'language used')]
# [('p', 'http://www.wikidata.org/prop/direct/P2959'), ('name', 'permanent duplicated item')]
# [('p', 'http://www.wikidata.org/prop/direct/P30'), ('name', 'continent')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('name', 'instance of')]
# [('p', 'http://www.wikidata.org/prop/direct/P35'), ('name', 'head of state')]
# [('p', 'http://www.wikidata.org/prop/direct/P36'), ('name', 'capital')]
# [('p', 'http://www.wikidata.org/prop/direct/P361'), ('name', 'part of')]
# [('p', 'http://www.wikidata.org/prop/direct/P37'), ('name', 'official language')]
# [('p', 'http://www.wikidata.org/prop/direct/P38'), ('name', 'currency')]
# [('p', 'http://www.wikidata.org/prop/direct/P3896'), ('name', 'geoshape')]
# 40

# %%
#nothing, but we'll just look for the BGP of France then. For that we need the PGB of country
queryString = """
SELECT DISTINCT ?o ?name 
WHERE {
   # bind something
   wd:Q38 wdt:P31 ?o .
   # ?o sc:name ?name .
   FILTER (!isLiteral(?o)).
} 
LIMIT 40
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('o', 'http://www.wikidata.org/entity/Q3624078'), ('name', 'sovereign state')]
# [('o', 'http://www.wikidata.org/entity/Q6256'), ('name', 'country')]
# 2

# %%
queryString = """
SELECT DISTINCT ?country ?name 
WHERE {
   # bind something
   wd:Q38 wdt:P30 ?continent .
   # ?country wdt:P31  wd:Q6256 ;
        wdt:P30 ?continent ;
        sc:name ?name .
} 
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('country', 'http://www.wikidata.org/entity/Q756617'), ('name', 'Danish Realm')]
# [('country', 'http://www.wikidata.org/entity/Q907112'), ('name', 'Transnistria')]
# [('country', 'http://www.wikidata.org/entity/Q142'), ('name', 'France')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('name', 'United Kingdom')]
# [('country', 'http://www.wikidata.org/entity/Q184'), ('name', 'Belarus')]
# [('country', 'http://www.wikidata.org/entity/Q20'), ('name', 'Norway')]
# [('country', 'http://www.wikidata.org/entity/Q211'), ('name', 'Latvia')]
# [('country', 'http://www.wikidata.org/entity/Q213'), ('name', 'Czech Republic')]
# [('country', 'http://www.wikidata.org/entity/Q214'), ('name', 'Slovakia')]
# [('country', 'http://www.wikidata.org/entity/Q218'), ('name', 'Romania')]
# [('country', 'http://www.wikidata.org/entity/Q219'), ('name', 'Bulgaria')]
# [('country', 'http://www.wikidata.org/entity/Q222'), ('name', 'Albania')]
# [('country', 'http://www.wikidata.org/entity/Q224'), ('name', 'Croatia')]
# [('country', 'http://www.wikidata.org/entity/Q228'), ('name', 'Andorra')]
# [('country', 'http://www.wikidata.org/entity/Q22880'), ('name', 'Electoral Palatinate')]
# [('country', 'http://www.wikidata.org/entity/Q229'), ('name', 'Cyprus')]
# [('country', 'http://www.wikidata.org/entity/Q232'), ('name', 'Kazakhstan')]
# [('country', 'http://www.wikidata.org/entity/Q233'), ('name', 'Malta')]
# [('country', 'http://www.wikidata.org/entity/Q236'), ('name', 'Montenegro')]
# [('country', 'http://www.wikidata.org/entity/Q25'), ('name', 'Wales')]
# 20

# %%
#and there we have the award received property
queryString = """
SELECT DISTINCT ?p ?name 
WHERE {
   # bind something
   wd:Q142 ?p ?o .
   # ?p sc:name ?name .
   FILTER (!isLiteral(?o)).
} 
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P1151'), ('name', "topic's main Wikimedia portal")]
# [('p', 'http://www.wikidata.org/prop/direct/P122'), ('name', 'basic form of government')]
# [('p', 'http://www.wikidata.org/prop/direct/P1313'), ('name', 'office held by head of government')]
# [('p', 'http://www.wikidata.org/prop/direct/P1325'), ('name', 'external data available at')]
# [('p', 'http://www.wikidata.org/prop/direct/P1343'), ('name', 'described by source')]
# [('p', 'http://www.wikidata.org/prop/direct/P1344'), ('name', 'participant in')]
# [('p', 'http://www.wikidata.org/prop/direct/P1365'), ('name', 'replaces')]
# [('p', 'http://www.wikidata.org/prop/direct/P138'), ('name', 'named after')]
# [('p', 'http://www.wikidata.org/prop/direct/P1464'), ('name', 'category for people born here')]
# [('p', 'http://www.wikidata.org/prop/direct/P1465'), ('name', 'category for people who died here')]
# [('p', 'http://www.wikidata.org/prop/direct/P1482'), ('name', 'Stack Exchange tag')]
# [('p', 'http://www.wikidata.org/prop/direct/P150'), ('name', 'contains administrative territorial entity')]
# [('p', 'http://www.wikidata.org/prop/direct/P1546'), ('name', 'motto')]
# [('p', 'http://www.wikidata.org/prop/direct/P1552'), ('name', 'has quality')]
# [('p', 'http://www.wikidata.org/prop/direct/P158'), ('name', 'seal image')]
# [('p', 'http://www.wikidata.org/prop/direct/P1589'), ('name', 'lowest point')]
# [('p', 'http://www.wikidata.org/prop/direct/P1622'), ('name', 'driving side')]
# [('p', 'http://www.wikidata.org/prop/direct/P163'), ('name', 'flag')]
# [('p', 'http://www.wikidata.org/prop/direct/P166'), ('name', 'award received')]
# [('p', 'http://www.wikidata.org/prop/direct/P17'), ('name', 'country')]
# 20

# %%
#we're looking a the prizes won by Italian poets
#Nobel prize is not there, but there is a lot of local prizes maybe reducing with those also receiving by French poets
queryString = """
SELECT DISTINCT ?award ?name
WHERE {
   # bind something
   # ?poet wdt:P106 wd:Q49757 ;
        wdt:P27 wd:Q38 ;
        wdt:P166 ?award .
   # ?award sc:name ?name .
} 
LIMIT 50
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('award', 'http://www.wikidata.org/entity/Q2108706'), ('name', 'Premio Campiello')]
# [('award', 'http://www.wikidata.org/entity/Q18608364'), ('name', 'Commander with star of the Order of St. Sylvester')]
# [('award', 'http://www.wikidata.org/entity/Q519214'), ('name', 'Nelly Sachs Prize')]
# [('award', 'http://www.wikidata.org/entity/Q7650000'), ('name', 'Sutherland Trophy')]
# [('award', 'http://www.wikidata.org/entity/Q1526935'), ('name', 'Viareggio Prize')]
# [('award', 'http://www.wikidata.org/entity/Q788568'), ('name', 'Bagutta Prize')]
# [('award', 'http://www.wikidata.org/entity/Q731542'), ('name', 'Strega Prize')]
# [('award', 'http://www.wikidata.org/entity/Q14539729'), ('name', 'Commander of the Order of Merit of the Italian Republic')]
# [('award', 'http://www.wikidata.org/entity/Q14539974'), ('name', 'Knight Grand Cross of the Order of Merit of the Italian Republic')]
# [('award', 'http://www.wikidata.org/entity/Q154590'), ('name', 'Golden Bear')]
# [('award', 'http://www.wikidata.org/entity/Q179808'), ('name', "Palme d'Or")]
# [('award', 'http://www.wikidata.org/entity/Q209459'), ('name', 'Golden Lion')]
# [('award', 'http://www.wikidata.org/entity/Q514445'), ('name', 'European Film Academy Lifetime Achievement Award')]
# [('award', 'http://www.wikidata.org/entity/Q3703463'), ('name', 'David di Donatello for Best Director')]
# [('award', 'http://www.wikidata.org/entity/Q727328'), ('name', 'Academy Honorary Award')]
# [('award', 'http://www.wikidata.org/entity/Q1315008'), ('name', 'National Society of Film Critics Award for Best Director')]
# [('award', 'http://www.wikidata.org/entity/Q599434'), ('name', 'Feltrinelli Prize')]
# [('award', 'http://www.wikidata.org/entity/Q1700510'), ('name', 'Golden Leopard')]
# [('award', 'http://www.wikidata.org/entity/Q164200'), ('name', 'Jury Prize')]
# [('award', 'http://www.wikidata.org/entity/Q3703245'), ('name', 'David Luchino Visconti')]
# [('award', 'http://www.wikidata.org/entity/Q55455135'), ('name', 'honorary doctorate of the Bordeaux Montaigne University')]
# [('award', 'http://www.wikidata.org/entity/Q844284'), ('name', 'Grawemeyer Award for Music Composition')]
# [('award', 'http://www.wikidata.org/entity/Q3910584'), ('name', 'Marzotto Prize')]
# [('award', 'http://www.wikidata.org/entity/Q3241784'), ('name', 'Golden Lion for Lifetime Achievements')]
# [('award', 'http://www.wikidata.org/entity/Q3870549'), ('name', "Nastro d'Argento for Best Actor")]
# [('award', 'http://www.wikidata.org/entity/Q2085270'), ('name', 'Order of the Badge of Honour')]
# [('award', 'http://www.wikidata.org/entity/Q791135'), ('name', 'Order of Friendship')]
# [('award', 'http://www.wikidata.org/entity/Q2268261'), ('name', 'Order of Honour')]
# [('award', 'http://www.wikidata.org/entity/Q3405076'), ('name', 'Prix Médicis for foreign literature')]
# [('award', 'http://www.wikidata.org/entity/Q60642820'), ('name', 'Viareggio-Versilia International Prize')]
# [('award', 'http://www.wikidata.org/entity/Q3404594'), ('name', 'Prix Formentor')]
# [('award', 'http://www.wikidata.org/entity/Q3405086'), ('name', 'Napoli Prize')]
# [('award', 'http://www.wikidata.org/entity/Q1662330'), ('name', "Globo d'oro")]
# [('award', 'http://www.wikidata.org/entity/Q3607619'), ('name', "Alabarda d'Oro Award")]
# [('award', 'http://www.wikidata.org/entity/Q1966051'), ('name', "Nastro d'Argento for Best Screenplay")]
# [('award', 'http://www.wikidata.org/entity/Q2089923'), ('name', 'Volpi Cup for Best Actor')]
# [('award', 'http://www.wikidata.org/entity/Q96382035'), ('name', 'Bonavera Prize')]
# [('award', 'http://www.wikidata.org/entity/Q327154'), ('name', 'Hans Christian Andersen Award')]
# [('award', 'http://www.wikidata.org/entity/Q128649'), ('name', 'David di Donatello for Best Actor')]
# [('award', 'http://www.wikidata.org/entity/Q13452528'), ('name', 'Chevalier des Arts et des Lettres')]
# [('award', 'http://www.wikidata.org/entity/Q20898906'), ('name', 'Golden Wreath')]
# [('award', 'http://www.wikidata.org/entity/Q2972198'), ('name', "Ciak d'oro")]
# [('award', 'http://www.wikidata.org/entity/Q96895980'), ('name', 'Honorary degree of the University of Macerata')]
# [('award', 'http://www.wikidata.org/entity/Q3870546'), ('name', "Nastro d'Argento for Best New Director")]
# [('award', 'http://www.wikidata.org/entity/Q978420'), ('name', 'Best Screenplay Award (Cannes Film Festival)')]
# [('award', 'http://www.wikidata.org/entity/Q674146'), ('name', 'Leopard of Honour')]
# [('award', 'http://www.wikidata.org/entity/Q1052227'), ('name', 'Kinema Junpo')]
# [('award', 'http://www.wikidata.org/entity/Q103360'), ('name', 'Academy Award for Best Director')]
# [('award', 'http://www.wikidata.org/entity/Q107258'), ('name', 'Academy Award for Best Writing, Adapted Screenplay')]
# [('award', 'http://www.wikidata.org/entity/Q10855271'), ('name', 'Knight of the Legion of Honour')]
# 50

# %%
#and there we (finally) have the Nobel Prize in Literature
queryString = """
SELECT DISTINCT ?award ?name
WHERE {
   # bind something
   # ?poet wdt:P106 wd:Q49757 ;
        wdt:P27 wd:Q38 ;
        wdt:P166 ?award .
   # ?fpoet wdt:P106 wd:Q49757 ;
        wdt:P27 wd:Q142 ;
        wdt:P166 ?award2 .
   # ?award sc:name ?name .
   FILTER(?award2 = ?award)
} 
LIMIT 50
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('award', 'http://www.wikidata.org/entity/Q519214'), ('name', 'Nelly Sachs Prize')]
# [('award', 'http://www.wikidata.org/entity/Q14539974'), ('name', 'Knight Grand Cross of the Order of Merit of the Italian Republic')]
# [('award', 'http://www.wikidata.org/entity/Q55455135'), ('name', 'honorary doctorate of the Bordeaux Montaigne University')]
# [('award', 'http://www.wikidata.org/entity/Q3405076'), ('name', 'Prix Médicis for foreign literature')]
# [('award', 'http://www.wikidata.org/entity/Q60642820'), ('name', 'Viareggio-Versilia International Prize')]
# [('award', 'http://www.wikidata.org/entity/Q3404594'), ('name', 'Prix Formentor')]
# [('award', 'http://www.wikidata.org/entity/Q13452528'), ('name', 'Chevalier des Arts et des Lettres')]
# [('award', 'http://www.wikidata.org/entity/Q20898906'), ('name', 'Golden Wreath')]
# [('award', 'http://www.wikidata.org/entity/Q674146'), ('name', 'Leopard of Honour')]
# [('award', 'http://www.wikidata.org/entity/Q10855271'), ('name', 'Knight of the Legion of Honour')]
# [('award', 'http://www.wikidata.org/entity/Q17985761'), ('name', 'star on Hollywood Walk of Fame')]
# [('award', 'http://www.wikidata.org/entity/Q3753203'), ('name', 'Gold Medal of Merit in the Fine Arts (Spain)')]
# [('award', 'http://www.wikidata.org/entity/Q580574'), ('name', 'Neustadt International Prize for Literature')]
# [('award', 'http://www.wikidata.org/entity/Q9052807'), ('name', 'Orden al Mérito Docente y Cultural Gabriela Mistral')]
# [('award', 'http://www.wikidata.org/entity/Q37922'), ('name', 'Nobel Prize in Literature')]
# [('award', 'http://www.wikidata.org/entity/Q57446605'), ('name', 'honorary doctor of the University of Padua')]
# [('award', 'http://www.wikidata.org/entity/Q16974791'), ('name', 'America Award in Literature')]
# [('award', 'http://www.wikidata.org/entity/Q50321301'), ('name', "prix de poésie de l'Académie française")]
# [('award', 'http://www.wikidata.org/entity/Q13452524'), ('name', 'Officier des Arts et des Lettres\u200e')]
# [('award', 'http://www.wikidata.org/entity/Q1141859'), ('name', 'Czech Medal of Merit')]
# [('award', 'http://www.wikidata.org/entity/Q2364347'), ('name', 'Andrei Biely Prize')]
# [('award', 'http://www.wikidata.org/entity/Q308907'), ('name', 'Lenin Peace Prize')]
# [('award', 'http://www.wikidata.org/entity/Q1139785'), ('name', "Saint George's Cross")]
# [('award', 'http://www.wikidata.org/entity/Q10855195'), ('name', 'Officer of the Legion of Honour')]
# [('award', 'http://www.wikidata.org/entity/Q14637188'), ('name', 'Commander of the French Order of Academic Palms')]
# [('award', 'http://www.wikidata.org/entity/Q3114788'), ('name', 'Grand prix de la francophonie')]
# 26

# %%
#according to wikipedia Dario Fo is not a poet so I'm verifying the result of my final query
#apparently no problem
queryString = """
SELECT DISTINCT ?o ?name
WHERE {
   # bind something
   wd:Q765 wdt:P106 ?o .
   # ?o sc:name ?name.
} 
LIMIT 50
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('o', 'http://www.wikidata.org/entity/Q2707485'), ('name', 'scenographer')]
# [('o', 'http://www.wikidata.org/entity/Q9334029'), ('name', 'satirist')]
# [('o', 'http://www.wikidata.org/entity/Q1028181'), ('name', 'painter')]
# [('o', 'http://www.wikidata.org/entity/Q10800557'), ('name', 'film actor')]
# [('o', 'http://www.wikidata.org/entity/Q214917'), ('name', 'playwright')]
# [('o', 'http://www.wikidata.org/entity/Q2259451'), ('name', 'stage actor')]
# [('o', 'http://www.wikidata.org/entity/Q28389'), ('name', 'screenwriter')]
# [('o', 'http://www.wikidata.org/entity/Q3387717'), ('name', 'theatrical director')]
# [('o', 'http://www.wikidata.org/entity/Q36180'), ('name', 'writer')]
# [('o', 'http://www.wikidata.org/entity/Q36834'), ('name', 'composer')]
# [('o', 'http://www.wikidata.org/entity/Q482980'), ('name', 'author')]
# [('o', 'http://www.wikidata.org/entity/Q49757'), ('name', 'poet')]
# [('o', 'http://www.wikidata.org/entity/Q644687'), ('name', 'illustrator')]
# [('o', 'http://www.wikidata.org/entity/Q1323191'), ('name', 'costume designer')]
# 14

# %%
#according to wikipedia there are other Italian poets who receive the Nobel Prize in Literature so I'm gonna verify the results of my final query
#We retrieve all the Italian receiving this Nobel Prize, apparently the data is just incomplete
queryString = """
SELECT DISTINCT ?italian ?name
WHERE {
   # bind something
   # ?italian wdt:P27 wd:Q38 ;
       wdt:P166 wd:Q37922 ;
       sc:name ?name.
} 
LIMIT 50
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('italian', 'http://www.wikidata.org/entity/Q765'), ('name', 'Dario Fo')]
# [('italian', 'http://www.wikidata.org/entity/Q83038'), ('name', 'Salvatore Quasimodo')]
# [('italian', 'http://www.wikidata.org/entity/Q83174'), ('name', 'Eugenio Montale')]
# 3

# %% [markdown]
# Final query for this task

# %%
# write your final query
queryString = """
SELECT DISTINCT ?poet ?name
WHERE {
   # bind something
   # ?poet wdt:P106 wd:Q49757 ;
        wdt:P27 wd:Q38 ;
        wdt:P166 wd:Q37922 ;
        sc:name ?name.
} 
LIMIT 50
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('poet', 'http://www.wikidata.org/entity/Q765'), ('name', 'Dario Fo')]
# [('poet', 'http://www.wikidata.org/entity/Q83038'), ('name', 'Salvatore Quasimodo')]
# [('poet', 'http://www.wikidata.org/entity/Q83174'), ('name', 'Eugenio Montale')]
# 3

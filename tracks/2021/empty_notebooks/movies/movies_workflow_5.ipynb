# %% [markdown]
# # General instructions
#
# The goal of the project is to materialize a set of **exploratory workloads** over a real-world, large-scale,  open-domain KG: [WikiData](https://www.wikidata.org/wiki/Wikidata:Main_Page)
#
# An exploratory workload  is composed by a set of queries, where each query is related to the information obtained previously.
#
# An exploratory workload starts with a usually vague, open ended question, and does not assume the person issuing the workload has a clear understanding of the data contained in the target database or its structure.
#
# Remeber that:
#
# 1. All the queries must run in the python notebook
# 2. You can use classes and properties only if you find them via a SPARQL query that must be present in the notebook
# 3. You do not delete useless queries. Keep everything that is synthatically valid
#
# ```
# ?p <http://schema.org/name> ?name .
# ```
#
#     is the BGP returning a human-readable name of a property or a class in Wikidata.

# %%
## SETUP used later

from SPARQLWrapper import SPARQLWrapper, JSON


prefixString = """
##-NOTEBOOK_CODE_HERE-##
PREFIX wd: <http://www.wikidata.org/entity/> 
PREFIX wdt: <http://www.wikidata.org/prop/direct/> 
PREFIX sc: <http://schema.org/>
"""

# select and construct queries
def run_query(queryString):
    to_run = prefixString + "\n" + queryString

    sparql = SPARQLWrapper("http://a256-gc1-03.srv.aau.dk:5820/sparql")
    sparql.setTimeout(300)
    sparql.setReturnFormat(JSON)
    sparql.setQuery(to_run)

    try :
       results = sparql.query()
       json_results = results.convert()
       if len(json_results['results']['bindings'])==0:
          print("Empty")
          return 0
    
       for bindings in json_results['results']['bindings']:
          print( [ (var, value['value'])  for var, value in bindings.items() ] )

       return len(json_results['results']['bindings'])

    except Exception as e :
        print("The operation failed", e)
    
# ASk queries
def run_ask_query(queryString):
    to_run = prefixString + "\n" + queryString

    sparql = SPARQLWrapper("http://a256-gc1-03.srv.aau.dk:5820/sparql")
    sparql.setTimeout(300)
    sparql.setReturnFormat(JSON)
    sparql.setQuery(to_run)

    try :
        return sparql.query().convert()

    except Exception as e :
        print("The operation failed", e)

# %% [markdown]
# ## Workflow 5
#
#
# Consider the following exploratory scenario:
#
#
# >  we are interested in western horror movies, a particular subgenre mixing two main genres: Horror and Western. We want to investigate what are the principal movies in the instersection between these two genres.
#
#
#
# ## Useful URIs for the current workflow
# The following are given:
#
# | IRI           | Description   | Role      |
# | -----------   | -----------   |-----------|
# | `wdt:P1647`   | subproperty   | predicate |
# | `wdt:P31`     | instance of   | predicate |
# | `wdt:P106`    | profession    | predicate |
# | `wdt:P279`    | subclass      | predicate |
# | `wdt:P136`    | genre      | predicate |
# | `wd:Q11424` | Film        | node |
# | `wd:Q835650` | Tremors        | node |
#
#
#
# Also consider
#
# ```
# wd:Q835650 ?p ?obj .
# ```
#
# is the BGP to retrieve all **properties of Tremors**
#
#
#
# The workload should
#
#
# 1. Return the titles of the western-horror movies (with data like year and director) in Wikidata
#
# 2. Investigate the number of films directed by the directors of the selected western-horror movies and then get information about the most productive three (films, most used actors in their movies, total revenues if available)
#
# 3. Get all the movies in the "Tremors" franchise and check if there are actors in the Tremors movies who also acted in any of the previously selected movies
#
# 4. Return how many of the actors who are members of the cast of the Tremors franchise have [Kavin Bacon number](https://en.wikipedia.org/wiki/Six_Degrees_of_Kevin_Bacon#:~:text=Kevin%20Bacon%20himself%20has%20a,Bacon%20number%20is%20N%2B1.) equal to 2

# %%
# start your workflow here

# %%
queryString = """
SELECT *
WHERE { 

wd:Q835650 ?p ?obj .

} 
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('p', 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), ('obj', 'http://wikiba.se/ontology#Item')]
# [('p', 'http://www.wikidata.org/prop/direct-normalized/P3212'), ('obj', 'urn:isan:0000-0000-7ADA-0000-8-0000-0000-D')]
# [('p', 'http://www.wikidata.org/prop/direct-normalized/P4276'), ('obj', 'https://data.cinematheque.qc.ca/data/Work56604')]
# [('p', 'http://www.wikidata.org/prop/direct-normalized/P646'), ('obj', 'http://g.co/kg/m/027ywq')]
# [('p', 'http://www.wikidata.org/prop/direct/P1040'), ('obj', 'http://www.wikidata.org/entity/Q1293442')]
# [('p', 'http://www.wikidata.org/prop/direct/P1237'), ('obj', 'tremors')]
# [('p', 'http://www.wikidata.org/prop/direct/P1258'), ('obj', 'm/tremors')]
# [('p', 'http://www.wikidata.org/prop/direct/P1265'), ('obj', '5674')]
# [('p', 'http://www.wikidata.org/prop/direct/P136'), ('obj', 'http://www.wikidata.org/entity/Q1065444')]
# [('p', 'http://www.wikidata.org/prop/direct/P136'), ('obj', 'http://www.wikidata.org/entity/Q157443')]
# [('p', 'http://www.wikidata.org/prop/direct/P136'), ('obj', 'http://www.wikidata.org/entity/Q188473')]
# [('p', 'http://www.wikidata.org/prop/direct/P136'), ('obj', 'http://www.wikidata.org/entity/Q200092')]
# [('p', 'http://www.wikidata.org/prop/direct/P136'), ('obj', 'http://www.wikidata.org/entity/Q2484376')]
# [('p', 'http://www.wikidata.org/prop/direct/P136'), ('obj', 'http://www.wikidata.org/entity/Q471839')]
# [('p', 'http://www.wikidata.org/prop/direct/P136'), ('obj', 'http://www.wikidata.org/entity/Q761469')]
# [('p', 'http://www.wikidata.org/prop/direct/P136'), ('obj', 'http://www.wikidata.org/entity/Q224700')]
# [('p', 'http://www.wikidata.org/prop/direct/P1476'), ('obj', 'Tremors')]
# [('p', 'http://www.wikidata.org/prop/direct/P1562'), ('obj', 'v50929')]
# [('p', 'http://www.wikidata.org/prop/direct/P161'), ('obj', 'http://www.wikidata.org/entity/Q463226')]
# [('p', 'http://www.wikidata.org/prop/direct/P161'), ('obj', 'http://www.wikidata.org/entity/Q3454165')]
# [('p', 'http://www.wikidata.org/prop/direct/P161'), ('obj', 'http://www.wikidata.org/entity/Q2442555')]
# [('p', 'http://www.wikidata.org/prop/direct/P161'), ('obj', 'http://www.wikidata.org/entity/Q350714')]
# [('p', 'http://www.wikidata.org/prop/direct/P161'), ('obj', 'http://www.wikidata.org/entity/Q964071')]
# [('p', 'http://www.wikidata.org/prop/direct/P161'), ('obj', 'http://www.wikidata.org/entity/Q264559')]
# [('p', 'http://www.wikidata.org/prop/direct/P161'), ('obj', 'http://www.wikidata.org/entity/Q1422655')]
# [('p', 'http://www.wikidata.org/prop/direct/P161'), ('obj', 'http://www.wikidata.org/entity/Q782662')]
# [('p', 'http://www.wikidata.org/prop/direct/P161'), ('obj', 'http://www.wikidata.org/entity/Q229430')]
# [('p', 'http://www.wikidata.org/prop/direct/P161'), ('obj', 'http://www.wikidata.org/entity/Q2411465')]
# [('p', 'http://www.wikidata.org/prop/direct/P161'), ('obj', 'http://www.wikidata.org/entity/Q443782')]
# [('p', 'http://www.wikidata.org/prop/direct/P162'), ('obj', 'http://www.wikidata.org/entity/Q269895')]
# [('p', 'http://www.wikidata.org/prop/direct/P162'), ('obj', 'http://www.wikidata.org/entity/Q1031927')]
# [('p', 'http://www.wikidata.org/prop/direct/P162'), ('obj', 'http://www.wikidata.org/entity/Q1101357')]
# [('p', 'http://www.wikidata.org/prop/direct/P1712'), ('obj', 'movie/tremors')]
# [('p', 'http://www.wikidata.org/prop/direct/P179'), ('obj', 'http://www.wikidata.org/entity/Q98112986')]
# [('p', 'http://www.wikidata.org/prop/direct/P1804'), ('obj', '7207')]
# [('p', 'http://www.wikidata.org/prop/direct/P1874'), ('obj', '60033108')]
# [('p', 'http://www.wikidata.org/prop/direct/P1889'), ('obj', 'http://www.wikidata.org/entity/Q2188675')]
# [('p', 'http://www.wikidata.org/prop/direct/P1970'), ('obj', '1248')]
# [('p', 'http://www.wikidata.org/prop/direct/P1981'), ('obj', 'http://www.wikidata.org/entity/Q20644797')]
# [('p', 'http://www.wikidata.org/prop/direct/P2047'), ('obj', '96')]
# [('p', 'http://www.wikidata.org/prop/direct/P2334'), ('obj', '18758')]
# [('p', 'http://www.wikidata.org/prop/direct/P2346'), ('obj', '134029')]
# [('p', 'http://www.wikidata.org/prop/direct/P2465'), ('obj', '16329')]
# [('p', 'http://www.wikidata.org/prop/direct/P2508'), ('obj', '6416')]
# [('p', 'http://www.wikidata.org/prop/direct/P2509'), ('obj', 'mv6405')]
# [('p', 'http://www.wikidata.org/prop/direct/P2518'), ('obj', '2973')]
# [('p', 'http://www.wikidata.org/prop/direct/P2529'), ('obj', '9262')]
# [('p', 'http://www.wikidata.org/prop/direct/P2603'), ('obj', '18440')]
# [('p', 'http://www.wikidata.org/prop/direct/P2631'), ('obj', '4408')]
# [('p', 'http://www.wikidata.org/prop/direct/P2638'), ('obj', 'movies/tremors')]
# [('p', 'http://www.wikidata.org/prop/direct/P2704'), ('obj', '10.5240/01D9-E8BC-D5CE-38F4-8C92-B')]
# [('p', 'http://www.wikidata.org/prop/direct/P272'), ('obj', 'http://www.wikidata.org/entity/Q21043034')]
# [('p', 'http://www.wikidata.org/prop/direct/P2747'), ('obj', 'http://www.wikidata.org/entity/Q23830578')]
# [('p', 'http://www.wikidata.org/prop/direct/P2755'), ('obj', '72938')]
# [('p', 'http://www.wikidata.org/prop/direct/P2758'), ('obj', 'http://www.wikidata.org/entity/Q23817729')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('obj', 'http://www.wikidata.org/entity/Q11424')]
# [('p', 'http://www.wikidata.org/prop/direct/P3107'), ('obj', '54392')]
# [('p', 'http://www.wikidata.org/prop/direct/P3110'), ('obj', '711')]
# [('p', 'http://www.wikidata.org/prop/direct/P3129'), ('obj', '715684')]
# [('p', 'http://www.wikidata.org/prop/direct/P3135'), ('obj', '2003312')]
# [('p', 'http://www.wikidata.org/prop/direct/P3138'), ('obj', '248')]
# [('p', 'http://www.wikidata.org/prop/direct/P3141'), ('obj', 't0004886')]
# [('p', 'http://www.wikidata.org/prop/direct/P3143'), ('obj', '100463')]
# [('p', 'http://www.wikidata.org/prop/direct/P3145'), ('obj', 'tt16154')]
# [('p', 'http://www.wikidata.org/prop/direct/P3203'), ('obj', '44678')]
# [('p', 'http://www.wikidata.org/prop/direct/P3212'), ('obj', '0000-0000-7ADA-0000-8-0000-0000-D')]
# [('p', 'http://www.wikidata.org/prop/direct/P3302'), ('obj', '9362')]
# [('p', 'http://www.wikidata.org/prop/direct/P344'), ('obj', 'http://www.wikidata.org/entity/Q1772301')]
# [('p', 'http://www.wikidata.org/prop/direct/P345'), ('obj', 'tt0100814')]
# [('p', 'http://www.wikidata.org/prop/direct/P3593'), ('obj', '58719')]
# [('p', 'http://www.wikidata.org/prop/direct/P364'), ('obj', 'http://www.wikidata.org/entity/Q1860')]
# [('p', 'http://www.wikidata.org/prop/direct/P3804'), ('obj', '127872')]
# [('p', 'http://www.wikidata.org/prop/direct/P3808'), ('obj', 'Tremors')]
# [('p', 'http://www.wikidata.org/prop/direct/P3844'), ('obj', '6175')]
# [('p', 'http://www.wikidata.org/prop/direct/P3933'), ('obj', '1294211')]
# [('p', 'http://www.wikidata.org/prop/direct/P4276'), ('obj', '56604')]
# [('p', 'http://www.wikidata.org/prop/direct/P437'), ('obj', 'http://www.wikidata.org/entity/Q723685')]
# [('p', 'http://www.wikidata.org/prop/direct/P4529'), ('obj', '1292599')]
# [('p', 'http://www.wikidata.org/prop/direct/P462'), ('obj', 'http://www.wikidata.org/entity/Q22006653')]
# [('p', 'http://www.wikidata.org/prop/direct/P4632'), ('obj', '1663')]
# [('p', 'http://www.wikidata.org/prop/direct/P4665'), ('obj', '4963')]
# [('p', 'http://www.wikidata.org/prop/direct/P480'), ('obj', '796625')]
# [('p', 'http://www.wikidata.org/prop/direct/P4947'), ('obj', '9362')]
# [('p', 'http://www.wikidata.org/prop/direct/P495'), ('obj', 'http://www.wikidata.org/entity/Q30')]
# [('p', 'http://www.wikidata.org/prop/direct/P5021'), ('obj', 'http://www.wikidata.org/entity/Q4165246')]
# [('p', 'http://www.wikidata.org/prop/direct/P5032'), ('obj', '11792')]
# [('p', 'http://www.wikidata.org/prop/direct/P5357'), ('obj', 'tremors')]
# [('p', 'http://www.wikidata.org/prop/direct/P57'), ('obj', 'http://www.wikidata.org/entity/Q1303837')]
# [('p', 'http://www.wikidata.org/prop/direct/P577'), ('obj', '1990-01-19T00:00:00Z')]
# [('p', 'http://www.wikidata.org/prop/direct/P577'), ('obj', '1990-05-17T00:00:00Z')]
# [('p', 'http://www.wikidata.org/prop/direct/P577'), ('obj', '1990-05-23T00:00:00Z')]
# [('p', 'http://www.wikidata.org/prop/direct/P5786'), ('obj', 'im-land-der-raketenwuermer')]
# [('p', 'http://www.wikidata.org/prop/direct/P58'), ('obj', 'http://www.wikidata.org/entity/Q1303837')]
# [('p', 'http://www.wikidata.org/prop/direct/P58'), ('obj', 'http://www.wikidata.org/entity/Q1031927')]
# [('p', 'http://www.wikidata.org/prop/direct/P58'), ('obj', 'http://www.wikidata.org/entity/Q1101357')]
# [('p', 'http://www.wikidata.org/prop/direct/P5970'), ('obj', 'http://www.wikidata.org/entity/Q80655145')]
# [('p', 'http://www.wikidata.org/prop/direct/P6127'), ('obj', 'tremors')]
# [('p', 'http://www.wikidata.org/prop/direct/P6398'), ('obj', '297911187')]
# [('p', 'http://www.wikidata.org/prop/direct/P646'), ('obj', '/m/027ywq')]
# [('p', 'http://www.wikidata.org/prop/direct/P6802'), ('obj', 'http://commons.wikimedia.org/wiki/Special:FilePath/01-2007-AlabamaHills-03.jpg')]
# [('p', 'http://www.wikidata.org/prop/direct/P750'), ('obj', 'http://www.wikidata.org/entity/Q1329615')]
# [('p', 'http://www.wikidata.org/prop/direct/P750'), ('obj', 'http://www.wikidata.org/entity/Q80948336')]
# [('p', 'http://www.wikidata.org/prop/direct/P750'), ('obj', 'http://www.wikidata.org/entity/Q907311')]
# [('p', 'http://www.wikidata.org/prop/direct/P7970'), ('obj', '1MV5a1c9fbdb43a672e7fefa3bb2a7f7a08')]
# [('p', 'http://www.wikidata.org/prop/direct/P8345'), ('obj', 'http://www.wikidata.org/entity/Q3998250')]
# [('p', 'http://www.wikidata.org/prop/direct/P840'), ('obj', 'http://www.wikidata.org/entity/Q2004038')]
# [('p', 'http://www.wikidata.org/prop/direct/P8411'), ('obj', 'http://www.wikidata.org/entity/Q8514')]
# [('p', 'http://www.wikidata.org/prop/direct/P86'), ('obj', 'http://www.wikidata.org/entity/Q1356550')]
# [('p', 'http://www.wikidata.org/prop/direct/P905'), ('obj', '10501')]
# [('p', 'http://www.wikidata.org/prop/direct/P910'), ('obj', 'http://www.wikidata.org/entity/Q32344468')]
# [('p', 'http://www.wikidata.org/prop/direct/P915'), ('obj', 'http://www.wikidata.org/entity/Q1854013')]
# [('p', 'http://www.wikidata.org/prop/direct/P915'), ('obj', 'http://www.wikidata.org/entity/Q99')]
# [('p', 'http://www.wikidata.org/prop/direct/P915'), ('obj', 'http://www.wikidata.org/entity/Q1505269')]
# [('p', 'http://www.wikidata.org/prop/direct/P915'), ('obj', 'http://www.wikidata.org/entity/Q2510895')]
# [('p', 'http://www.wikidata.org/prop/direct/P9586'), ('obj', 'umc.cmc.7jb3styubx294bfiv2gt1zl01')]
# [('p', 'http://schema.org/name'), ('obj', 'Tremors')]
# [('p', 'http://www.wikidata.org/prop/direct/P7975'), ('obj', '515')]
# 117

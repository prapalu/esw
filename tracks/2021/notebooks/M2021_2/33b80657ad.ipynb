# %% [markdown]
# # General instructions
#
# The goal of the project is to materialize a set of **exploratory workloads** over a real-world, large-scale,  open-domain KG: [WikiData](https://www.wikidata.org/wiki/Wikidata:Main_Page)
#
# An exploratory workload  is composed by a set of queries, where each query is related to the information obtained previously.
#
# An exploratory workload starts with a usually vague, open ended question, and does not assume the person issuing the workload has a clear understanding of the data contained in the target database or its structure.
#
# Remeber that:
#
# 1. All the queries must run in the python notebook
# 2. You can use classes and properties only if you find them via a SPARQL query that must be present in the notebook
# 3. You do not delete useless queries. Keep everything that is synthatically valid
#
# ```
# ?p <http://schema.org/name> ?name .
# ```
#
# is the BGP returning a human-readable name of a property or a class in Wikidata.

# %%
## SETUP used later

from SPARQLWrapper import SPARQLWrapper, JSON


prefixString = """
##-33b80657ad-##
PREFIX wd: <http://www.wikidata.org/entity/> 
PREFIX wdt: <http://www.wikidata.org/prop/direct/> 
PREFIX sc: <http://schema.org/>
"""

# select and construct queries
def run_query(queryString):
    to_run = prefixString + "\n" + queryString

    sparql = SPARQLWrapper("http://a256-gc1-02.srv.aau.dk:5820/sparql")
    #sparql = SPARQLWrapper("http://a256-gc1-03.srv.aau.dk:5820/sparql")
    sparql.setTimeout(300)
    sparql.setReturnFormat(JSON)
    sparql.setQuery(to_run)

    try :
       results = sparql.query()
       json_results = results.convert()
       if len(json_results['results']['bindings'])==0:
          print("Empty")
          return 0
    
       for bindings in json_results['results']['bindings']:
          print( [ (var, value['value'])  for var, value in bindings.items() ] )

       return len(json_results['results']['bindings'])

    except Exception as e :
        print("The operation failed", e)
    
# ASk queries
def run_ask_query(queryString):
    to_run = prefixString + "\n" + queryString
    
    sparql = SPARQLWrapper("http://a256-gc1-02.srv.aau.dk:5820/sparql")
    #sparql = SPARQLWrapper("http://a256-gc1-03.srv.aau.dk:5820/sparql")
    sparql.setTimeout(300)
    sparql.setReturnFormat(JSON)
    sparql.setQuery(to_run)

    try :
        return sparql.query().convert()

    except Exception as e :
        print("The operation failed", e)

# %% [markdown]
# # Companies Workflow Series ("IT Companies explorative search")
#
# Consider the following exploratory information need:
#
# > Compare companies across different sectors in U.K., U.S., and Canada, consider number of employees, companies owned or acquired, and revenue or assets

# %% [markdown]
# ## Useful URIs for the current workflow
#
#
# The following are given:
#
# | IRI           | Description   | Role      |
# | -----------   | -----------   |-----------|
# | `wdt:P1647`   | subproperty   | predicate |
# | `wdt:P31`     | instance of   | predicate |
# | `wdt:P279`    | subclass      | predicate |
# | `wdt:P17`      | country       | predicate |
# | `wd:Q4830453`  | Business      | node      |
# | `wd:Q13977`    | Bloomberg L.P.| node |
# | `wd:Q502121`   | BlackBerry    | node |
# | `wd:Q16`        | Canada        | node |
# | `wd:Q145`      | U.K.          | node |
# | `wd:Q30`       | U.S.A.        | node |
#
#
# Also consider
#
# ```
# ?p wdt:P17 wd:Q16  .
# ?p wdt:P31 wd:Q4830453  .
# ```
#
# is the BGP to retrieve all **canadian businesses**

# %% [markdown]
# ## Workload Goals
#
# 1. Identify the BGP for obtaining number of employees of a company and other relevant numerical attributes
#
# 2. Identify the BGP to retrieve all companies owned by a company
#
# 3. Is there some company that owns companies in other countries?
#
# 4. Companies have different 'legal forms', compare the number of companies divided in different legal forms
#
# 5. Analyze the number of employees  and other relevant numeric attributes
#
#    5.1 What are the top-10 companies for a given attribute?
#
#    5.2 For which companies is defined some form of income or market capitalization or total assets? What is the min, max, and average in each category and country?
#
#    5.3 Which business in each country owns more businesses in other countries?

# %%
#testing query to get name of properties and classes
q = f"""
select ?name where{{
wdt:P17 <http://schema.org/name> ?name
}}
"""
run_query(q)
# Out:
# [('name', 'country')]
# 1

# %%
#get all canadian businesses (with name)
#limit output to avoid scrolling too much
q = f"""
select ?business ?name where{{
# ?business wdt:P17 wd:Q16 ;
    wdt:P31 wd:Q4830453 ;
    <http://schema.org/name> ?name
}}
limit(10)
"""
run_query(q)
# Out:
# [('business', 'http://www.wikidata.org/entity/Q17107879'), ('name', 'Martin & Vleminckx')]
# [('business', 'http://www.wikidata.org/entity/Q3347600'), ('name', 'OMERS')]
# [('business', 'http://www.wikidata.org/entity/Q4724292'), ('name', 'Algoma Central')]
# [('business', 'http://www.wikidata.org/entity/Q1647539'), ('name', 'Royal Canadian Mint')]
# [('business', 'http://www.wikidata.org/entity/Q17012723'), ('name', 'Nova Scotia Light and Power')]
# [('business', 'http://www.wikidata.org/entity/Q3499025'), ('name', 'Fresh TV')]
# [('business', 'http://www.wikidata.org/entity/Q6934764'), ('name', 'Multimatic Motorsports')]
# [('business', 'http://www.wikidata.org/entity/Q10439578'), ('name', 'Calgary Sports and Entertainment')]
# [('business', 'http://www.wikidata.org/entity/Q7059529'), ('name', 'Northland Power')]
# [('business', 'http://www.wikidata.org/entity/Q29123207'), ('name', 'Stryker (Canada)')]
# 10

# %%
#we want to find the uri and the name for UK, US, Canada to focus our exploratory search on those 3
q = f"""
select ?country ?name where{{
# ?country wdt:P31 wdt:P17 ;
    <http://schema.org/name> ?name .
filter regex(?name, '.*(uk|us|Canada|UK|US|U.K|U.S|United Kingdom|United States).*')
}}
"""
run_query(q)
# Out:
# Empty
# 0

# %%
#probably something wrong with the regex, let's try and find only Canada even if we already have its uri
q = f"""
select ?country ?name where{{
# ?country wdt:P31 wdt:P17 ;
    <http://schema.org/name> ?name .
filter regex(?name, '.*(C|c)(anada|ANADA).*')
}}
"""
run_query(q)
# Out:
# Empty
# 0

# %%
#let's try this instead: get 10 countries with their name
q = f"""
select ?country ?name where{{
# ?country wdt:P31 wdt:P17 ;
    <http://schema.org/name> ?name .
}}
limit(10)
"""
run_query(q)
# Out:
# Empty
# 0

# %%
#let's try and get only countries without their name
q = f"""
select ?country where{{
# ?country wdt:P31 wdt:P17
}}
limit(10)
"""
run_query(q)
# Out:
# Empty
# 0

# %%
#try and run a query that gave us results before
q = f"""
select ?business ?name where{{
# ?business wdt:P17 wd:Q16 ;
    wdt:P31 wd:Q4830453 ;
    <http://schema.org/name> ?name
}}
limit(10)
"""
run_query(q)
# Out:
# [('business', 'http://www.wikidata.org/entity/Q17107879'), ('name', 'Martin & Vleminckx')]
# [('business', 'http://www.wikidata.org/entity/Q3347600'), ('name', 'OMERS')]
# [('business', 'http://www.wikidata.org/entity/Q4724292'), ('name', 'Algoma Central')]
# [('business', 'http://www.wikidata.org/entity/Q1647539'), ('name', 'Royal Canadian Mint')]
# [('business', 'http://www.wikidata.org/entity/Q17012723'), ('name', 'Nova Scotia Light and Power')]
# [('business', 'http://www.wikidata.org/entity/Q3499025'), ('name', 'Fresh TV')]
# [('business', 'http://www.wikidata.org/entity/Q6934764'), ('name', 'Multimatic Motorsports')]
# [('business', 'http://www.wikidata.org/entity/Q10439578'), ('name', 'Calgary Sports and Entertainment')]
# [('business', 'http://www.wikidata.org/entity/Q7059529'), ('name', 'Northland Power')]
# [('business', 'http://www.wikidata.org/entity/Q29123207'), ('name', 'Stryker (Canada)')]
# 10

# %%
#i got confused: wdt:P17 is a property, not a class
#let's try again and get US, UK, Canada as we wanted
q = f"""
select distinct ?country ?name where{{
    # ?subject wdt:P17 ?country .
    # ?country <http://schema.org/name> ?name .
    filter regex(?name, '.*(uk|us|Canada|UK|US|U.K|U.S|United Kingdom|United States).*')
}}

"""
run_query(q)
# Out:
# [('country', 'http://www.wikidata.org/entity/Q3088906'), ('name', 'France–United Kingdom border')]
# [('country', 'http://www.wikidata.org/entity/Q106577'), ('name', 'Neustria')]
# [('country', 'http://www.wikidata.org/entity/Q208169'), ('name', 'Republic of Ragusa')]
# [('country', 'http://www.wikidata.org/entity/Q5677983'), ('name', 'Indigenous reservation')]
# [('country', 'http://www.wikidata.org/entity/Q1061488'), ('name', 'United States of Colombia')]
# [('country', 'http://www.wikidata.org/entity/Q11285099'), ('name', 'United States occupation of the Ryukyu Islands')]
# [('country', 'http://www.wikidata.org/entity/Q76236'), ('name', 'Lithuanian–Belorussian Soviet Socialist Republic')]
# [('country', 'http://www.wikidata.org/entity/Q19128339'), ('name', 'American Russians')]
# [('country', 'http://www.wikidata.org/entity/Q12631'), ('name', 'Meuse')]
# [('country', 'http://www.wikidata.org/entity/Q139319'), ('name', 'Russian Republic')]
# [('country', 'http://www.wikidata.org/entity/Q190967'), ('name', 'Crusader states')]
# [('country', 'http://www.wikidata.org/entity/Q23681'), ('name', 'Turkish Republic of Northern Cyprus')]
# [('country', 'http://www.wikidata.org/entity/Q268970'), ('name', 'Republic of German-Austria')]
# [('country', 'http://www.wikidata.org/entity/Q282428'), ('name', 'Mamluk Sultanate')]
# [('country', 'http://www.wikidata.org/entity/Q55502'), ('name', 'Kingdom of Jerusalem')]
# [('country', 'http://www.wikidata.org/entity/Q1768199'), ('name', 'Great Russian Encyclopedia')]
# [('country', 'http://www.wikidata.org/entity/Q123559'), ('name', 'al-Andalus')]
# [('country', 'http://www.wikidata.org/entity/Q136968'), ('name', 'Anochetus')]
# [('country', 'http://www.wikidata.org/entity/Q17376095'), ('name', 'cadastral municipality of Austria')]
# [('country', 'http://www.wikidata.org/entity/Q879050'), ('name', 'manor house')]
# [('country', 'http://www.wikidata.org/entity/Q2569593'), ('name', 'Canada')]
# [('country', 'http://www.wikidata.org/entity/Q842199'), ('name', "Belarusian People's Republic")]
# [('country', 'http://www.wikidata.org/entity/Q7380487'), ('name', 'Kingdom of Pontus')]
# [('country', 'http://www.wikidata.org/entity/Q2914461'), ('name', 'Autonomous Republic of Abkhazia')]
# [('country', 'http://www.wikidata.org/entity/Q3624335'), ('name', 'Duchy of Austria')]
# [('country', 'http://www.wikidata.org/entity/Q700283'), ('name', 'Austrian Netherlands')]
# [('country', 'http://www.wikidata.org/entity/Q187684'), ('name', 'Despotate of Epirus')]
# [('country', 'http://www.wikidata.org/entity/Q213638'), ('name', 'Kingdom of Cyprus')]
# [('country', 'http://www.wikidata.org/entity/Q1027'), ('name', 'Mauritius')]
# [('country', 'http://www.wikidata.org/entity/Q11223'), ('name', 'United States Air Force')]
# [('country', 'http://www.wikidata.org/entity/Q11703'), ('name', 'United States Virgin Islands')]
# [('country', 'http://www.wikidata.org/entity/Q1218'), ('name', 'Jerusalem')]
# [('country', 'http://www.wikidata.org/entity/Q139671'), ('name', 'Crimean Autonomous Soviet Socialist Republic')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('name', 'United Kingdom')]
# [('country', 'http://www.wikidata.org/entity/Q157367'), ('name', 'Brandenburg-Prussia')]
# [('country', 'http://www.wikidata.org/entity/Q15864'), ('name', 'United Kingdom of the Netherlands')]
# [('country', 'http://www.wikidata.org/entity/Q159'), ('name', 'Russia')]
# [('country', 'http://www.wikidata.org/entity/Q16'), ('name', 'Canada')]
# [('country', 'http://www.wikidata.org/entity/Q161036'), ('name', 'Free State of Prussia')]
# [('country', 'http://www.wikidata.org/entity/Q16559'), ('name', 'Austin')]
# [('country', 'http://www.wikidata.org/entity/Q174193'), ('name', 'United Kingdom of Great Britain and Ireland')]
# [('country', 'http://www.wikidata.org/entity/Q176495'), ('name', 'Federal State of Austria')]
# [('country', 'http://www.wikidata.org/entity/Q182565'), ('name', 'Phuket')]
# [('country', 'http://www.wikidata.org/entity/Q184'), ('name', 'Belarus')]
# [('country', 'http://www.wikidata.org/entity/Q186096'), ('name', 'Tsardom of Russia')]
# [('country', 'http://www.wikidata.org/entity/Q2164'), ('name', 'Nenets Autonomous Okrug')]
# [('country', 'http://www.wikidata.org/entity/Q229'), ('name', 'Cyprus')]
# [('country', 'http://www.wikidata.org/entity/Q2305208'), ('name', 'Russian Socialist Federative Soviet Republic')]
# [('country', 'http://www.wikidata.org/entity/Q27306'), ('name', 'Kingdom of Prussia')]
# [('country', 'http://www.wikidata.org/entity/Q30'), ('name', 'United States of America')]
# [('country', 'http://www.wikidata.org/entity/Q34266'), ('name', 'Russian Empire')]
# [('country', 'http://www.wikidata.org/entity/Q40'), ('name', 'Austria')]
# [('country', 'http://www.wikidata.org/entity/Q408'), ('name', 'Australia')]
# [('country', 'http://www.wikidata.org/entity/Q42497'), ('name', 'Lower Austria')]
# [('country', 'http://www.wikidata.org/entity/Q4398229'), ('name', 'Russian state 1918-1920')]
# [('country', 'http://www.wikidata.org/entity/Q518101'), ('name', 'First Republic of Austria')]
# [('country', 'http://www.wikidata.org/entity/Q5848651'), ('name', 'United States of Venezuela')]
# [('country', 'http://www.wikidata.org/entity/Q6320'), ('name', 'Khanty-Mansi Autonomous Okrug')]
# [('country', 'http://www.wikidata.org/entity/Q639100'), ('name', 'Principality of Reuss-Gera')]
# [('country', 'http://www.wikidata.org/entity/Q6407'), ('name', 'Yamalo-Nenets Autonomous Okrug')]
# [('country', 'http://www.wikidata.org/entity/Q746558'), ('name', 'Emirate of Bukhara')]
# [('country', 'http://www.wikidata.org/entity/Q771'), ('name', 'Massachusetts')]
# [('country', 'http://www.wikidata.org/entity/Q7737'), ('name', 'Russian')]
# [('country', 'http://www.wikidata.org/entity/Q7984'), ('name', 'Chukotka Autonomous Okrug')]
# [('country', 'http://www.wikidata.org/entity/Q809806'), ('name', 'Bashkir Autonomous Soviet Socialist Republic')]
# [('country', 'http://www.wikidata.org/entity/Q9091'), ('name', 'Belarusian')]
# [('country', 'http://www.wikidata.org/entity/Q188650'), ('name', 'Lusitania')]
# [('country', 'http://www.wikidata.org/entity/Q131964'), ('name', 'Austrian Empire')]
# [('country', 'http://www.wikidata.org/entity/Q154849'), ('name', 'Grand Duchy of Tuscany')]
# [('country', 'http://www.wikidata.org/entity/Q200229'), ('name', 'House of Savoy')]
# [('country', 'http://www.wikidata.org/entity/Q22866'), ('name', 'SV Austria Salzburg')]
# [('country', 'http://www.wikidata.org/entity/Q26180'), ('name', 'Sint Eustatius')]
# [('country', 'http://www.wikidata.org/entity/Q28025'), ('name', 'Ryukyu Kingdom')]
# [('country', 'http://www.wikidata.org/entity/Q28513'), ('name', 'Austria-Hungary')]
# [('country', 'http://www.wikidata.org/entity/Q2895'), ('name', 'Byelorussian Soviet Socialist Republic')]
# [('country', 'http://www.wikidata.org/entity/Q35715'), ('name', 'South Australia')]
# [('country', 'http://www.wikidata.org/entity/Q38872'), ('name', 'Prussia')]
# [('country', 'http://www.wikidata.org/entity/Q3995'), ('name', 'Basque Autonomous Community')]
# [('country', 'http://www.wikidata.org/entity/Q41967'), ('name', 'Upper Austria')]
# [('country', 'http://www.wikidata.org/entity/Q7721124'), ('name', 'The Canadas')]
# [('country', 'http://www.wikidata.org/entity/Q625649'), ('name', 'Aram-Damascus')]
# [('country', 'http://www.wikidata.org/entity/Q1063498'), ('name', 'United States of the Ionian Islands')]
# [('country', 'http://www.wikidata.org/entity/Q3765117'), ('name', 'Eastern Chalukyas')]
# [('country', 'http://www.wikidata.org/entity/Q2424466'), ('name', 'Caucasus Viceroyalty')]
# [('country', 'http://www.wikidata.org/entity/Q3813830'), ('name', 'Justanids')]
# [('country', 'http://www.wikidata.org/entity/Q62109505'), ('name', 'Austrian Lombardy')]
# [('country', 'http://www.wikidata.org/entity/Q68678'), ('name', 'Socialist Soviet Republic of Byelorussia')]
# [('country', 'http://www.wikidata.org/entity/Q9391434'), ('name', 'United Kingdom of Poland')]
# [('country', 'http://www.wikidata.org/entity/Q4304392'), ('name', 'Russian State')]
# [('country', 'http://www.wikidata.org/entity/Q105567983'), ('name', 'United States Army Field artillery battalion')]
# [('country', 'http://www.wikidata.org/entity/Q105568320'), ('name', 'United States Army Field artillery regiment')]
# [('country', 'http://www.wikidata.org/entity/Q105098'), ('name', 'Austrasia')]
# [('country', 'http://www.wikidata.org/entity/Q484104'), ('name', 'United States Army Military Government in Korea')]
# [('country', 'http://www.wikidata.org/entity/Q1108445'), ('name', "Kievan Rus'")]
# [('country', 'http://www.wikidata.org/entity/Q18869'), ('name', 'Caucasus')]
# [('country', 'http://www.wikidata.org/entity/Q2332797'), ('name', 'Kazak Autonomous Socialist Soviet Republic')]
# [('country', 'http://www.wikidata.org/entity/Q2600622'), ('name', 'Leshukonsky District')]
# [('country', 'http://www.wikidata.org/entity/Q3206'), ('name', 'Western Australia')]
# [('country', 'http://www.wikidata.org/entity/Q32530'), ('name', 'Lusatia')]
# [('country', 'http://www.wikidata.org/entity/Q37736'), ('name', 'North Caucasus')]
# [('country', 'http://www.wikidata.org/entity/Q3960'), ('name', 'Australia')]
# [('country', 'http://www.wikidata.org/entity/Q609850'), ('name', 'Rus')]
# [('country', 'http://www.wikidata.org/entity/Q903779'), ('name', 'United Kingdom of Portugal, Brazil and the Algarves')]
# [('country', 'http://www.wikidata.org/entity/Q153091'), ('name', 'Duchy of Prussia')]
# [('country', 'http://www.wikidata.org/entity/Q699964'), ('name', 'Archduchy of Austria')]
# [('country', 'http://www.wikidata.org/entity/Q103801'), ('name', 'East Prussia')]
# [('country', 'http://www.wikidata.org/entity/Q157734'), ('name', 'Muscat and Oman')]
# [('country', 'http://www.wikidata.org/entity/Q30623'), ('name', 'Manchukuo')]
# [('country', 'http://www.wikidata.org/entity/Q131083'), ('name', 'Nakhchivan Autonomous Republic')]
# [('country', 'http://www.wikidata.org/entity/Q5219'), ('name', 'Republic of Ingushetia')]
# [('country', 'http://www.wikidata.org/entity/Q644636'), ('name', 'Cyprus')]
# [('country', 'http://www.wikidata.org/entity/Q619829'), ('name', 'Autonomous Administration of North and East Syria')]
# [('country', 'http://www.wikidata.org/entity/Q277760'), ('name', 'gatehouse')]
# [('country', 'http://www.wikidata.org/entity/Q3708094'), ('name', 'Seljuk Empire')]
# [('country', 'http://www.wikidata.org/entity/Q5783'), ('name', 'Andalusia')]
# [('country', 'http://www.wikidata.org/entity/Q1143805'), ('name', 'United States national rugby union team')]
# [('country', 'http://www.wikidata.org/entity/Q4533605'), ('name', 'South Russia')]
# [('country', 'http://www.wikidata.org/entity/Q6940348'), ('name', 'Muscogee (Creek) Nation')]
# [('country', 'http://www.wikidata.org/entity/Q21409375'), ('name', "North-Eastern Rus'")]
# [('country', 'http://www.wikidata.org/entity/Q2369687'), ('name', 'Susiana')]
# [('country', 'http://www.wikidata.org/entity/Q2992254'), ('name', 'Armed Forces of South Russia')]
# [('country', 'http://www.wikidata.org/entity/Q7132429'), ('name', 'Papal States under Pope Pius IX')]
# [('country', 'http://www.wikidata.org/entity/Q616221'), ('name', 'Trust Territory of Somalia')]
# [('country', 'http://www.wikidata.org/entity/Q15240466'), ('name', 'British Cyprus')]
# [('country', 'http://www.wikidata.org/entity/Q16712671'), ('name', 'Flag of the Emirate of Bukhara')]
# [('country', 'http://www.wikidata.org/entity/Q577668'), ('name', 'Khanate of Bukhara')]
# [('country', 'http://www.wikidata.org/entity/Q68682'), ('name', "Bukharan People's Soviet Republic")]
# [('country', 'http://www.wikidata.org/entity/Q178994'), ('name', 'Australian Antarctic Territory')]
# [('country', 'http://www.wikidata.org/entity/Q212938'), ('name', 'East Jerusalem')]
# [('country', 'http://www.wikidata.org/entity/Q1134180'), ('name', 'Lower Canada')]
# [('country', 'http://www.wikidata.org/entity/Q788056'), ('name', 'Komi Autonomous Soviet Socialist Republic')]
# [('country', 'http://www.wikidata.org/entity/Q10531418'), ('name', 'imperial house of the Yuan Empire')]
# [('country', 'http://www.wikidata.org/entity/Q16645'), ('name', 'United States Minor Outlying Islands')]
# [('country', 'http://www.wikidata.org/entity/Q1438983'), ('name', 'Untsukulsky District')]
# [('country', 'http://www.wikidata.org/entity/Q795427'), ('name', 'Upper Canada')]
# [('country', 'http://www.wikidata.org/entity/Q1121436'), ('name', 'Province of Canada')]
# [('country', 'http://www.wikidata.org/entity/Q729570'), ('name', 'Ruso')]
# [('country', 'http://www.wikidata.org/entity/Q57676556'), ('name', 'Colony of Western Australia')]
# [('country', 'http://www.wikidata.org/entity/Q4994210'), ('name', 'Husie')]
# [('country', 'http://www.wikidata.org/entity/Q2600170'), ('name', 'Kirghiz Autonomous Socialist Soviet Republic')]
# [('country', 'http://www.wikidata.org/entity/Q523435'), ('name', 'United States of Indonesia')]
# [('country', 'http://www.wikidata.org/entity/Q84853'), ('name', 'Russa')]
# [('country', 'http://www.wikidata.org/entity/Q853968'), ('name', 'Hindustan')]
# [('country', 'http://www.wikidata.org/entity/Q779924'), ('name', 'Muslim world')]
# [('country', 'http://www.wikidata.org/entity/Q1362233'), ('name', 'Upper Lusatian house')]
# [('country', 'http://www.wikidata.org/entity/Q55416584'), ('name', 'continental United States')]
# [('country', 'http://www.wikidata.org/entity/Q241790'), ('name', 'Kush')]
# [('country', 'http://www.wikidata.org/entity/Q1867844'), ('name', 'March of Tuscany')]
# [('country', 'http://www.wikidata.org/entity/Q14759030'), ('name', 'Commonwealth realm of Mauritius')]
# [('country', 'http://www.wikidata.org/entity/Q660702'), ('name', 'Further Austria')]
# [('country', 'http://www.wikidata.org/entity/Q913382'), ('name', 'Bithynia et Pontus')]
# [('country', 'http://www.wikidata.org/entity/Q19971019'), ('name', 'United States of America')]
# [('country', 'http://www.wikidata.org/entity/Q25979'), ('name', 'Kushan Empire')]
# [('country', 'http://www.wikidata.org/entity/Q99281400'), ('name', 'United States of America')]
# [('country', 'http://www.wikidata.org/entity/Q99292697'), ('name', 'Russia')]
# [('country', 'http://www.wikidata.org/entity/Q99292789'), ('name', 'United Kingdom of Great Britain and Northern Ireland')]
# [('country', 'http://www.wikidata.org/entity/Q1334322'), ('name', 'County of Toulouse')]
# [('country', 'http://www.wikidata.org/entity/Q58826'), ('name', 'Caucasus Emirate')]
# [('country', 'http://www.wikidata.org/entity/Q12053604'), ('name', 'British Mauritius')]
# [('country', 'http://www.wikidata.org/entity/Q13574822'), ('name', 'Orchomenus')]
# [('country', 'http://www.wikidata.org/entity/Q784851'), ('name', 'Turkish Federated State of Cyprus')]
# [('country', 'http://www.wikidata.org/entity/Q398720'), ('name', 'Russia')]
# [('country', 'http://www.wikidata.org/entity/Q2478280'), ('name', 'Ormus')]
# [('country', 'http://www.wikidata.org/entity/Q7865620'), ('name', 'URSS')]
# [('country', 'http://www.wikidata.org/entity/Q1392840'), ('name', "Novgorodian Rus'")]
# [('country', 'http://www.wikidata.org/entity/Q238047'), ('name', 'Euskadi')]
# [('country', 'http://www.wikidata.org/entity/Q1028133'), ('name', 'Autonomous Albanian Republic of Korçë')]
# [('country', 'http://www.wikidata.org/entity/Q4881953'), ('name', 'Belarusian democracy movement')]
# [('country', 'http://www.wikidata.org/entity/Q3655944'), ('name', 'Autonomous Governorate of Estonia')]
# [('country', 'http://www.wikidata.org/entity/Q2935756'), ('name', 'Canada East')]
# [('country', 'http://www.wikidata.org/entity/Q18763208'), ('name', 'Kush')]
# [('country', 'http://www.wikidata.org/entity/Q630163'), ('name', 'Schwarzburg-Sondershausen')]
# [('country', 'http://www.wikidata.org/entity/Q9360397'), ('name', 'Toussaint')]
# [('country', 'http://www.wikidata.org/entity/Q12054842'), ('name', 'Autonomous Land of Slovakia')]
# [('country', 'http://www.wikidata.org/entity/Q3456436'), ('name', 'Republic of Lower Canada')]
# [('country', 'http://www.wikidata.org/entity/Q4397927'), ('name', 'Russian Democratic Federative Republic')]
# [('country', 'http://www.wikidata.org/entity/Q22349149'), ('name', 'Duchy of Tuscany')]
# [('country', 'http://www.wikidata.org/entity/Q91901863'), ('name', 'Drusselstein')]
# [('country', 'http://www.wikidata.org/entity/Q12552451'), ('name', 'Maykuduk')]
# 179

# %%
#let's try and find the uri for the the class Country using the uri for Canada, already provided
q = f"""
select ?o ?name where{{
wd:Q16 wdt:P31 ?o .
# ?o <http://schema.org/name> ?name
}}
"""
run_query(q)
# Out:
# [('o', 'http://www.wikidata.org/entity/Q3624078'), ('name', 'sovereign state')]
# [('o', 'http://www.wikidata.org/entity/Q6256'), ('name', 'country')]
# 2

# %%
#now we can easily isolate instances of country
class_country = 'wd:Q6256'
#let's try and find again the uris for Canada, United States, United Kingdom
q = f"""
select ?country ?name where{{
# ?country wdt:P31 wd:Q6256 ;
    <http://schema.org/name> ?name
filter regex(?name, '(united kingdom|canada|united states of america)' ,'i')
}}

"""
run_query(q)
# Out:
# [('country', 'http://www.wikidata.org/entity/Q145'), ('name', 'United Kingdom')]
# [('country', 'http://www.wikidata.org/entity/Q16'), ('name', 'Canada')]
# [('country', 'http://www.wikidata.org/entity/Q30'), ('name', 'United States of America')]
# 3

# %%
#let's try and get all of the properties associated with a business, with their names
q = f"""
select distinct ?property ?propertyName where{{
# ?b wdt:P31 wd:Q4830453 .
# ?b ?property ?predicate .
# ?property <http://schema.org/name> ?propertyName
}}
"""
run_query(q)
# Out:
# [('property', 'http://www.wikidata.org/prop/direct/P4446'), ('propertyName', 'reward program')]
# [('property', 'http://www.wikidata.org/prop/direct/P1268'), ('propertyName', 'represents')]
# [('property', 'http://www.wikidata.org/prop/direct/P2751'), ('propertyName', 'Roller Coaster Database ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3376'), ('propertyName', 'Enterprise number (Belgium)')]
# [('property', 'http://www.wikidata.org/prop/direct/P6617'), ('propertyName', 'RoMEO publisher ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7403'), ('propertyName', 'Publons publisher ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7972'), ('propertyName', 'CVR person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P8562'), ('propertyName', 'JSTOR publisher ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5505'), ('propertyName', 'WorldCat Registry ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7639'), ('propertyName', 'OverDrive publisher ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P101'), ('propertyName', 'field of work')]
# [('property', 'http://www.wikidata.org/prop/direct/P1037'), ('propertyName', 'director / manager')]
# [('property', 'http://www.wikidata.org/prop/direct/P1056'), ('propertyName', 'product or material produced')]
# [('property', 'http://www.wikidata.org/prop/direct/P112'), ('propertyName', 'founded by')]
# [('property', 'http://www.wikidata.org/prop/direct/P1128'), ('propertyName', 'employees')]
# [('property', 'http://www.wikidata.org/prop/direct/P1207'), ('propertyName', 'NUKAT ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P127'), ('propertyName', 'owned by')]
# [('property', 'http://www.wikidata.org/prop/direct/P1278'), ('propertyName', 'Legal Entity Identifier')]
# [('property', 'http://www.wikidata.org/prop/direct/P1280'), ('propertyName', 'CONOR.SI ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P131'), ('propertyName', 'located in the administrative territorial entity')]
# [('property', 'http://www.wikidata.org/prop/direct/P1320'), ('propertyName', 'OpenCorporates ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1343'), ('propertyName', 'described by source')]
# [('property', 'http://www.wikidata.org/prop/direct/P1365'), ('propertyName', 'replaces')]
# [('property', 'http://www.wikidata.org/prop/direct/P138'), ('propertyName', 'named after')]
# [('property', 'http://www.wikidata.org/prop/direct/P1417'), ('propertyName', 'Encyclopædia Britannica Online ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1448'), ('propertyName', 'official name')]
# [('property', 'http://www.wikidata.org/prop/direct/P1451'), ('propertyName', 'motto text')]
# [('property', 'http://www.wikidata.org/prop/direct/P1454'), ('propertyName', 'legal form')]
# [('property', 'http://www.wikidata.org/prop/direct/P154'), ('propertyName', 'logo image')]
# [('property', 'http://www.wikidata.org/prop/direct/P155'), ('propertyName', 'follows')]
# [('property', 'http://www.wikidata.org/prop/direct/P156'), ('propertyName', 'followed by')]
# [('property', 'http://www.wikidata.org/prop/direct/P1566'), ('propertyName', 'GeoNames ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P159'), ('propertyName', 'headquarters location')]
# [('property', 'http://www.wikidata.org/prop/direct/P1619'), ('propertyName', 'date of official opening')]
# [('property', 'http://www.wikidata.org/prop/direct/P166'), ('propertyName', 'award received')]
# [('property', 'http://www.wikidata.org/prop/direct/P1661'), ('propertyName', 'Alexa rank')]
# [('property', 'http://www.wikidata.org/prop/direct/P1670'), ('propertyName', 'Canadiana Authorities ID (former scheme)')]
# [('property', 'http://www.wikidata.org/prop/direct/P169'), ('propertyName', 'chief executive officer')]
# [('property', 'http://www.wikidata.org/prop/direct/P17'), ('propertyName', 'country')]
# [('property', 'http://www.wikidata.org/prop/direct/P1705'), ('propertyName', 'native label')]
# [('property', 'http://www.wikidata.org/prop/direct/P176'), ('propertyName', 'manufacturer')]
# [('property', 'http://www.wikidata.org/prop/direct/P1789'), ('propertyName', 'chief operating officer')]
# [('property', 'http://www.wikidata.org/prop/direct/P18'), ('propertyName', 'image')]
# [('property', 'http://www.wikidata.org/prop/direct/P1830'), ('propertyName', 'owner of')]
# [('property', 'http://www.wikidata.org/prop/direct/P1889'), ('propertyName', 'different from')]
# [('property', 'http://www.wikidata.org/prop/direct/P1942'), ('propertyName', 'McCune-Reischauer romanization')]
# [('property', 'http://www.wikidata.org/prop/direct/P2001'), ('propertyName', 'Revised Romanization')]
# [('property', 'http://www.wikidata.org/prop/direct/P2002'), ('propertyName', 'Twitter username')]
# [('property', 'http://www.wikidata.org/prop/direct/P2003'), ('propertyName', 'Instagram username')]
# [('property', 'http://www.wikidata.org/prop/direct/P2013'), ('propertyName', 'Facebook ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2088'), ('propertyName', 'Crunchbase organization ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P213'), ('propertyName', 'ISNI')]
# [('property', 'http://www.wikidata.org/prop/direct/P2139'), ('propertyName', 'total revenue')]
# [('property', 'http://www.wikidata.org/prop/direct/P214'), ('propertyName', 'VIAF ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P227'), ('propertyName', 'GND ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2283'), ('propertyName', 'uses')]
# [('property', 'http://www.wikidata.org/prop/direct/P2295'), ('propertyName', 'net profit')]
# [('property', 'http://www.wikidata.org/prop/direct/P2397'), ('propertyName', 'YouTube channel ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2403'), ('propertyName', 'total assets')]
# [('property', 'http://www.wikidata.org/prop/direct/P2427'), ('propertyName', 'GRID ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P244'), ('propertyName', 'Library of Congress authority ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2581'), ('propertyName', 'BabelNet ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2671'), ('propertyName', 'Google Knowledge Graph ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P268'), ('propertyName', 'Bibliothèque nationale de France ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P281'), ('propertyName', 'postal code')]
# [('property', 'http://www.wikidata.org/prop/direct/P2847'), ('propertyName', 'Google+ ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P31'), ('propertyName', 'instance of')]
# [('property', 'http://www.wikidata.org/prop/direct/P3153'), ('propertyName', 'Crossref funder ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3221'), ('propertyName', 'New York Times topic ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3225'), ('propertyName', 'Corporate Number (Japan)')]
# [('property', 'http://www.wikidata.org/prop/direct/P3347'), ('propertyName', 'PermID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3362'), ('propertyName', 'operating income')]
# [('property', 'http://www.wikidata.org/prop/direct/P3393'), ('propertyName', 'LittleSis organization ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3417'), ('propertyName', 'Quora topic ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P349'), ('propertyName', 'National Diet Library ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3500'), ('propertyName', 'Ringgold ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P355'), ('propertyName', 'subsidiary')]
# [('property', 'http://www.wikidata.org/prop/direct/P3553'), ('propertyName', 'Zhihu topic ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3608'), ('propertyName', 'EU VAT number')]
# [('property', 'http://www.wikidata.org/prop/direct/P361'), ('propertyName', 'part of')]
# [('property', 'http://www.wikidata.org/prop/direct/P373'), ('propertyName', 'Commons category')]
# [('property', 'http://www.wikidata.org/prop/direct/P3749'), ('propertyName', 'Google Maps Customer ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3793'), ('propertyName', 'IPv6 routing prefix')]
# [('property', 'http://www.wikidata.org/prop/direct/P3836'), ('propertyName', 'Pinterest username')]
# [('property', 'http://www.wikidata.org/prop/direct/P3987'), ('propertyName', 'SHARE Catalogue author ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P414'), ('propertyName', 'stock exchange')]
# [('property', 'http://www.wikidata.org/prop/direct/P4204'), ('propertyName', 'The Times of India topic ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4264'), ('propertyName', 'LinkedIn company ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4293'), ('propertyName', 'PM20 folder ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P452'), ('propertyName', 'industry')]
# [('property', 'http://www.wikidata.org/prop/direct/P4527'), ('propertyName', 'UK Parliament thesaurus ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P463'), ('propertyName', 'member of')]
# [('property', 'http://www.wikidata.org/prop/direct/P4839'), ('propertyName', 'Wolfram Language entity code')]
# [('property', 'http://www.wikidata.org/prop/direct/P488'), ('propertyName', 'chairperson')]
# [('property', 'http://www.wikidata.org/prop/direct/P5008'), ('propertyName', 'on focus list of Wikimedia project')]
# [('property', 'http://www.wikidata.org/prop/direct/P5161'), ('propertyName', 'Trustpilot company ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P528'), ('propertyName', 'catalog code')]
# [('property', 'http://www.wikidata.org/prop/direct/P571'), ('propertyName', 'inception')]
# [('property', 'http://www.wikidata.org/prop/direct/P576'), ('propertyName', 'dissolved, abolished or demolished date')]
# [('property', 'http://www.wikidata.org/prop/direct/P5769'), ('propertyName', 'editor-in-chief')]
# [('property', 'http://www.wikidata.org/prop/direct/P5785'), ('propertyName', 'EU Research participant ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P582'), ('propertyName', 'end time')]
# [('property', 'http://www.wikidata.org/prop/direct/P6363'), ('propertyName', 'WordLift URL')]
# [('property', 'http://www.wikidata.org/prop/direct/P6366'), ('propertyName', 'Microsoft Academic ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6379'), ('propertyName', 'has works in the collection')]
# [('property', 'http://www.wikidata.org/prop/direct/P646'), ('propertyName', 'Freebase ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6698'), ('propertyName', 'Japan Search name ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6760'), ('propertyName', 'Know Your Meme ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6782'), ('propertyName', 'ROR ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P691'), ('propertyName', 'NKCR AUT ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7084'), ('propertyName', 'related category')]
# [('property', 'http://www.wikidata.org/prop/direct/P7293'), ('propertyName', 'PLWABN ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7306'), ('propertyName', 'Downdetector ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P740'), ('propertyName', 'location of formation')]
# [('property', 'http://www.wikidata.org/prop/direct/P749'), ('propertyName', 'parent organization')]
# [('property', 'http://www.wikidata.org/prop/direct/P7859'), ('propertyName', 'WorldCat Identities ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7886'), ('propertyName', 'Media Arts Database ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P793'), ('propertyName', 'significant event')]
# [('property', 'http://www.wikidata.org/prop/direct/P8253'), ('propertyName', 'OSM Name Suggestion Index identifier')]
# [('property', 'http://www.wikidata.org/prop/direct/P856'), ('propertyName', 'official website')]
# [('property', 'http://www.wikidata.org/prop/direct/P8687'), ('propertyName', 'social media followers')]
# [('property', 'http://www.wikidata.org/prop/direct/P910'), ('propertyName', "topic's main category")]
# [('property', 'http://www.wikidata.org/prop/direct/P9152'), ('propertyName', 'CollectieGelderland creator ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P935'), ('propertyName', 'Commons gallery')]
# [('property', 'http://www.wikidata.org/prop/direct/P946'), ('propertyName', 'ISIN')]
# [('property', 'http://www.wikidata.org/prop/direct/P949'), ('propertyName', 'National Library of Israel ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P973'), ('propertyName', 'described at URL')]
# [('property', 'http://www.wikidata.org/prop/direct/P3242'), ('propertyName', 'SIC code')]
# [('property', 'http://www.wikidata.org/prop/direct/P5531'), ('propertyName', 'Central Index Key')]
# [('property', 'http://www.wikidata.org/prop/direct/P1059'), ('propertyName', 'CVR number')]
# [('property', 'http://www.wikidata.org/prop/direct/P121'), ('propertyName', 'item operated')]
# [('property', 'http://www.wikidata.org/prop/direct/P2137'), ('propertyName', 'total equity')]
# [('property', 'http://www.wikidata.org/prop/direct/P2905'), ('propertyName', 'RateBeer brewery ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3035'), ('propertyName', 'ISBN publisher prefix')]
# [('property', 'http://www.wikidata.org/prop/direct/P3579'), ('propertyName', 'Sina Weibo user ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4156'), ('propertyName', 'Czech Registration ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6160'), ('propertyName', 'BoardGameGeek game publisher ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6375'), ('propertyName', 'street address')]
# [('property', 'http://www.wikidata.org/prop/direct/P6795'), ('propertyName', 'Unified Social Credit Identifier')]
# [('property', 'http://www.wikidata.org/prop/direct/P8987'), ('propertyName', 'ISDS ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P113'), ('propertyName', 'airline hub')]
# [('property', 'http://www.wikidata.org/prop/direct/P114'), ('propertyName', 'airline alliance')]
# [('property', 'http://www.wikidata.org/prop/direct/P1662'), ('propertyName', 'DOI prefix')]
# [('property', 'http://www.wikidata.org/prop/direct/P229'), ('propertyName', 'IATA airline designator')]
# [('property', 'http://www.wikidata.org/prop/direct/P230'), ('propertyName', 'ICAO airline designator')]
# [('property', 'http://www.wikidata.org/prop/direct/P2333'), ('propertyName', 'Norwegian organisation number')]
# [('property', 'http://www.wikidata.org/prop/direct/P432'), ('propertyName', 'callsign of airline')]
# [('property', 'http://www.wikidata.org/prop/direct/P5703'), ('propertyName', 'airline accounting code')]
# [('property', 'http://www.wikidata.org/prop/direct/P7769'), ('propertyName', 'Australian National Maritime Museum person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7534'), ('propertyName', 'MIC market code')]
# [('property', 'http://www.wikidata.org/prop/direct/P7729'), ('propertyName', 'GUI number')]
# [('property', 'http://www.wikidata.org/prop/direct/P2138'), ('propertyName', 'total liabilities')]
# [('property', 'http://www.wikidata.org/prop/direct/P8340'), ('propertyName', 'estimated value')]
# [('property', 'http://www.wikidata.org/prop/direct/P5062'), ('propertyName', 'DOAB publisher ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2904'), ('propertyName', 'Beer Advocate brewery ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2814'), ('propertyName', 'P-number')]
# [('property', 'http://www.wikidata.org/prop/direct/P4840'), ('propertyName', 'Directory of Czech publishers ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P8174'), ('propertyName', 'Slovak Registration ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2486'), ('propertyName', 'FMD brand ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P9279'), ('propertyName', 'Egapro gender equality index')]
# [('property', 'http://www.wikidata.org/prop/direct/P1015'), ('propertyName', 'NORAF ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1273'), ('propertyName', 'CANTIC ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1315'), ('propertyName', 'NLA Trove ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1329'), ('propertyName', 'phone number')]
# [('property', 'http://www.wikidata.org/prop/direct/P1344'), ('propertyName', 'participant in')]
# [('property', 'http://www.wikidata.org/prop/direct/P1366'), ('propertyName', 'replaced by')]
# [('property', 'http://www.wikidata.org/prop/direct/P1581'), ('propertyName', 'official blog')]
# [('property', 'http://www.wikidata.org/prop/direct/P1616'), ('propertyName', 'SIREN number')]
# [('property', 'http://www.wikidata.org/prop/direct/P163'), ('propertyName', 'flag')]
# [('property', 'http://www.wikidata.org/prop/direct/P1813'), ('propertyName', 'short name')]
# [('property', 'http://www.wikidata.org/prop/direct/P2041'), ('propertyName', 'National Gallery of Victoria artist ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2174'), ('propertyName', 'Museum of Modern Art artist ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2650'), ('propertyName', 'interested in')]
# [('property', 'http://www.wikidata.org/prop/direct/P269'), ('propertyName', 'IdRef ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P271'), ('propertyName', 'CiNii author ID (books)')]
# [('property', 'http://www.wikidata.org/prop/direct/P276'), ('propertyName', 'location')]
# [('property', 'http://www.wikidata.org/prop/direct/P3381'), ('propertyName', 'File Format Wiki page ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P345'), ('propertyName', 'IMDb ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P366'), ('propertyName', 'use')]
# [('property', 'http://www.wikidata.org/prop/direct/P3794'), ('propertyName', 'Dictionary of Sydney ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3861'), ('propertyName', 'App Store app ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3984'), ('propertyName', 'subreddit')]
# [('property', 'http://www.wikidata.org/prop/direct/P3988'), ('propertyName', 'National Library Board Singapore ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4013'), ('propertyName', 'Giphy username')]
# [('property', 'http://www.wikidata.org/prop/direct/P41'), ('propertyName', 'flag image')]
# [('property', 'http://www.wikidata.org/prop/direct/P4773'), ('propertyName', 'MobyGames company ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P495'), ('propertyName', 'country of origin')]
# [('property', 'http://www.wikidata.org/prop/direct/P7085'), ('propertyName', 'TikTok username')]
# [('property', 'http://www.wikidata.org/prop/direct/P7763'), ('propertyName', 'copyright status as a creator')]
# [('property', 'http://www.wikidata.org/prop/direct/P7982'), ('propertyName', 'Hrvatska enciklopedija ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P8350'), ('propertyName', 'Singapore Infopedia ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P8408'), ('propertyName', 'KBpedia ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P906'), ('propertyName', 'SELIBR ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P921'), ('propertyName', 'main subject')]
# [('property', 'http://www.wikidata.org/prop/direct/P966'), ('propertyName', 'MusicBrainz label ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P968'), ('propertyName', 'email address')]
# [('property', 'http://www.wikidata.org/prop/direct/P4936'), ('propertyName', 'SFMOMA artist ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2622'), ('propertyName', 'Companies House company ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2782'), ('propertyName', 'Models.com client ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3404'), ('propertyName', 'The Vogue List ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4691'), ('propertyName', 'OpenSecrets organization ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3482'), ('propertyName', 'Europeana Fashion creator ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1951'), ('propertyName', 'investor')]
# [('property', 'http://www.wikidata.org/prop/direct/P9782'), ('propertyName', 'Tax Identification Number (Belarus)')]
# [('property', 'http://www.wikidata.org/prop/direct/P8346'), ('propertyName', 'Nomor Pokok Wajib Pajak (organisation or corporation)')]
# [('property', 'http://www.wikidata.org/prop/direct/P1239'), ('propertyName', 'ISFDB publisher ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P854'), ('propertyName', 'reference URL')]
# [('property', 'http://www.wikidata.org/prop/direct/P1167'), ('propertyName', 'USB vendor ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1296'), ('propertyName', 'Gran Enciclopèdia Catalana ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1482'), ('propertyName', 'Stack Exchange tag')]
# [('property', 'http://www.wikidata.org/prop/direct/P1771'), ('propertyName', 'Integrated Postsecondary Education Data System ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2037'), ('propertyName', 'GitHub username')]
# [('property', 'http://www.wikidata.org/prop/direct/P2572'), ('propertyName', 'hashtag')]
# [('property', 'http://www.wikidata.org/prop/direct/P2657'), ('propertyName', 'EU Transparency Register ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3301'), ('propertyName', 'broadcast by')]
# [('property', 'http://www.wikidata.org/prop/direct/P371'), ('propertyName', 'presenter')]
# [('property', 'http://www.wikidata.org/prop/direct/P3761'), ('propertyName', 'IPv4 routing prefix')]
# [('property', 'http://www.wikidata.org/prop/direct/P407'), ('propertyName', 'language of work or name')]
# [('property', 'http://www.wikidata.org/prop/direct/P4486'), ('propertyName', 'Google Play developer ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5909'), ('propertyName', 'HKCAN ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P641'), ('propertyName', 'sport')]
# [('property', 'http://www.wikidata.org/prop/direct/P6773'), ('propertyName', 'HAL structure ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P989'), ('propertyName', 'spoken text audio')]
# [('property', 'http://www.wikidata.org/prop/direct/P4265'), ('propertyName', 'Reddit username')]
# [('property', 'http://www.wikidata.org/prop/direct/P6460'), ('propertyName', 'Swedish Organization Number')]
# [('property', 'http://www.wikidata.org/prop/direct/P7438'), ('propertyName', 'FantLab publisher ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7477'), ('propertyName', 'Internet Content Provider Registration Record ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1840'), ('propertyName', 'investigated by')]
# [('property', 'http://www.wikidata.org/prop/direct/P106'), ('propertyName', 'occupation')]
# [('property', 'http://www.wikidata.org/prop/direct/P1317'), ('propertyName', 'floruit')]
# [('property', 'http://www.wikidata.org/prop/direct/P1814'), ('propertyName', 'name in kana')]
# [('property', 'http://www.wikidata.org/prop/direct/P1988'), ('propertyName', 'Le Delarge ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2043'), ('propertyName', 'length')]
# [('property', 'http://www.wikidata.org/prop/direct/P2048'), ('propertyName', 'height')]
# [('property', 'http://www.wikidata.org/prop/direct/P2049'), ('propertyName', 'width')]
# [('property', 'http://www.wikidata.org/prop/direct/P2163'), ('propertyName', 'FAST ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2342'), ('propertyName', 'AGORHA person/institution ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P245'), ('propertyName', 'Union List of Artist Names ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2750'), ('propertyName', "Photographers' Identities Catalog ID")]
# [('property', 'http://www.wikidata.org/prop/direct/P2936'), ('propertyName', 'language used')]
# [('property', 'http://www.wikidata.org/prop/direct/P3342'), ('propertyName', 'significant person')]
# [('property', 'http://www.wikidata.org/prop/direct/P3569'), ('propertyName', 'Cultureel Woordenboek ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3630'), ('propertyName', 'Babelio author ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4342'), ('propertyName', 'Store norske leksikon ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P437'), ('propertyName', 'distribution format')]
# [('property', 'http://www.wikidata.org/prop/direct/P650'), ('propertyName', 'RKDartists ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7128'), ('propertyName', 'Archives Directory for the History of Collecting in America ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7157'), ('propertyName', 'The Top Tens ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7831'), ('propertyName', 'NMVW ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P8317'), ('propertyName', 'Philadelphia Museum of Art entity ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P8406'), ('propertyName', 'Grove Art Online ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P92'), ('propertyName', 'main regulatory text')]
# [('property', 'http://www.wikidata.org/prop/direct/P950'), ('propertyName', 'Biblioteca Nacional de España ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6645'), ('propertyName', 'Stedelijk Museum Amsterdam ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P9201'), ('propertyName', 'Norwegian State Administration Database ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5887'), ('propertyName', 'Arkivportalen agent ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P8053'), ('propertyName', 'Latvian unified registration number')]
# [('property', 'http://www.wikidata.org/prop/direct/P4829'), ('propertyName', 'Swiss Enterprise Identification Number')]
# [('property', 'http://www.wikidata.org/prop/direct/P6202'), ('propertyName', 'Geolex ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1299'), ('propertyName', 'depicted by')]
# [('property', 'http://www.wikidata.org/prop/direct/P136'), ('propertyName', 'genre')]
# [('property', 'http://www.wikidata.org/prop/direct/P1424'), ('propertyName', "topic's main template")]
# [('property', 'http://www.wikidata.org/prop/direct/P1711'), ('propertyName', 'British Museum person or institution ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1816'), ('propertyName', 'National Portrait Gallery (London) person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1953'), ('propertyName', 'Discogs artist ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2011'), ('propertyName', 'Cooper-Hewitt Person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2046'), ('propertyName', 'area')]
# [('property', 'http://www.wikidata.org/prop/direct/P2541'), ('propertyName', 'operating area')]
# [('property', 'http://www.wikidata.org/prop/direct/P3222'), ('propertyName', 'NE.se ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3544'), ('propertyName', 'Te Papa agent ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3603'), ('propertyName', 'Minneapolis Institute of Art constituent ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4553'), ('propertyName', 'RA Collections ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4776'), ('propertyName', 'MAC Address Block Large ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4808'), ('propertyName', 'Royal Academy new identifier')]
# [('property', 'http://www.wikidata.org/prop/direct/P485'), ('propertyName', 'archives at')]
# [('property', 'http://www.wikidata.org/prop/direct/P5247'), ('propertyName', 'Giant Bomb ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5266'), ('propertyName', 'Finnish national bibliography corporate name ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5508'), ('propertyName', 'archINFORM person or group ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6295'), ('propertyName', 'ARTIC artist ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6619'), ('propertyName', 'XING company ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6706'), ('propertyName', 'De Agostini ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7703'), ('propertyName', 'Spanish Quora topic ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7901'), ('propertyName', 'Encyclopedia of Chicago ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7936'), ('propertyName', 'business model')]
# [('property', 'http://www.wikidata.org/prop/direct/P9756'), ('propertyName', 'Schoenberg Database of Manuscripts name ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2179'), ('propertyName', 'ACM Classification Code (2012)')]
# [('property', 'http://www.wikidata.org/prop/direct/P7101'), ('propertyName', 'privacy policy URL')]
# [('property', 'http://www.wikidata.org/prop/direct/P2014'), ('propertyName', 'Museum of Modern Art work ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3502'), ('propertyName', 'Ameblo username')]
# [('property', 'http://www.wikidata.org/prop/direct/P3642'), ('propertyName', 'ARCHON code')]
# [('property', 'http://www.wikidata.org/prop/direct/P8645'), ('propertyName', 'Energy Identification Code')]
# [('property', 'http://www.wikidata.org/prop/direct/P249'), ('propertyName', 'ticker symbol')]
# [('property', 'http://www.wikidata.org/prop/direct/P8060'), ('propertyName', 'Glassdoor company ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3744'), ('propertyName', 'number of subscribers')]
# [('property', 'http://www.wikidata.org/prop/direct/P6182'), ('propertyName', 'GameFAQs company ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4411'), ('propertyName', 'Quora username')]
# [('property', 'http://www.wikidata.org/prop/direct/P3098'), ('propertyName', 'ClinicalTrials.gov ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1019'), ('propertyName', 'web feed URL')]
# [('property', 'http://www.wikidata.org/prop/direct/P170'), ('propertyName', 'creator')]
# [('property', 'http://www.wikidata.org/prop/direct/P2627'), ('propertyName', 'ISO 9362 SWIFT/BIC code')]
# [('property', 'http://www.wikidata.org/prop/direct/P2900'), ('propertyName', 'fax number')]
# [('property', 'http://www.wikidata.org/prop/direct/P3108'), ('propertyName', 'Yelp ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3418'), ('propertyName', 'Google Play Store app ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3430'), ('propertyName', 'SNAC ARK ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3509'), ('propertyName', 'Dagens Nyheter topic ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3511'), ('propertyName', 'VGMDb organization ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3743'), ('propertyName', 'ITU/ISO/IEC object identifier')]
# [('property', 'http://www.wikidata.org/prop/direct/P3797'), ('propertyName', 'autonomous system number')]
# [('property', 'http://www.wikidata.org/prop/direct/P3888'), ('propertyName', 'Boijmans artist ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3999'), ('propertyName', 'date of official closure')]
# [('property', 'http://www.wikidata.org/prop/direct/P421'), ('propertyName', 'located in time zone')]
# [('property', 'http://www.wikidata.org/prop/direct/P444'), ('propertyName', 'review score')]
# [('property', 'http://www.wikidata.org/prop/direct/P5260'), ('propertyName', 'App Store developer ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6157'), ('propertyName', 'Google News publication ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6839'), ('propertyName', 'TV Tropes identifier')]
# [('property', 'http://www.wikidata.org/prop/direct/P6849'), ('propertyName', 'DR topic ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7642'), ('propertyName', 'TheGamesDB publisher ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P8972'), ('propertyName', 'small logo or icon')]
# [('property', 'http://www.wikidata.org/prop/direct/P898'), ('propertyName', 'IPA transcription')]
# [('property', 'http://www.wikidata.org/prop/direct/P9035'), ('propertyName', 'Muck Rack media outlet ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P998'), ('propertyName', 'Curlie ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2984'), ('propertyName', 'Snapchat username')]
# [('property', 'http://www.wikidata.org/prop/direct/P3215'), ('propertyName', 'SIRET number')]
# [('property', 'http://www.wikidata.org/prop/direct/P7560'), ('propertyName', 'UVL company ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7634'), ('propertyName', 'TheGamesDB developer ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7784'), ('propertyName', 'LaunchBox Games Database developer ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7810'), ('propertyName', 'LaunchBox Games Database publisher ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7997'), ('propertyName', 'GRY-Online company ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3679'), ('propertyName', 'stock market index')]
# [('property', 'http://www.wikidata.org/prop/direct/P3002'), ('propertyName', 'Untappd brewery ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3224'), ('propertyName', 'NAICS code')]
# [('property', 'http://www.wikidata.org/prop/direct/P2699'), ('propertyName', 'URL')]
# [('property', 'http://www.wikidata.org/prop/direct/P3281'), ('propertyName', 'French National Assembly Lobbyist ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6518'), ('propertyName', 'Business Registry code (Estonia)')]
# [('property', 'http://www.wikidata.org/prop/direct/P9321'), ('propertyName', 'Inforegister ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5285'), ('propertyName', 'Firmenbuchnummer')]
# [('property', 'http://www.wikidata.org/prop/direct/P2226'), ('propertyName', 'market capitalization')]
# [('property', 'http://www.wikidata.org/prop/direct/P2561'), ('propertyName', 'name')]
# [('property', 'http://www.wikidata.org/prop/direct/P2666'), ('propertyName', 'Datahub page')]
# [('property', 'http://www.wikidata.org/prop/direct/P3320'), ('propertyName', 'board member')]
# [('property', 'http://www.wikidata.org/prop/direct/P6269'), ('propertyName', 'API endpoint')]
# [('property', 'http://www.wikidata.org/prop/direct/P8571'), ('propertyName', 'external auditor')]
# [('property', 'http://www.wikidata.org/prop/direct/P8605'), ('propertyName', 'Linked Open Data Cloud identifier')]
# [('property', 'http://www.wikidata.org/prop/direct/P902'), ('propertyName', 'HDS ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1716'), ('propertyName', 'brand')]
# [('property', 'http://www.wikidata.org/prop/direct/P5052'), ('propertyName', 'supervisory board member')]
# [('property', 'http://www.wikidata.org/prop/direct/P6422'), ('propertyName', 'ManualsLib brand ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3548'), ('propertyName', 'Australian Business Number')]
# [('property', 'http://www.wikidata.org/prop/direct/P3549'), ('propertyName', 'Australian Company Number')]
# [('property', 'http://www.wikidata.org/prop/direct/P3447'), ('propertyName', 'mirrors data from')]
# [('property', 'http://www.wikidata.org/prop/direct/P1004'), ('propertyName', 'MusicBrainz place ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P137'), ('propertyName', 'operator')]
# [('property', 'http://www.wikidata.org/prop/direct/P1807'), ('propertyName', 'Great Aragonese Encyclopedia ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3029'), ('propertyName', 'UK National Archives ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3065'), ('propertyName', 'RERO ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3365'), ('propertyName', 'Treccani ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P360'), ('propertyName', 'is a list of')]
# [('property', 'http://www.wikidata.org/prop/direct/P409'), ('propertyName', 'Libraries Australia ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4195'), ('propertyName', 'category for employees of the organization')]
# [('property', 'http://www.wikidata.org/prop/direct/P6262'), ('propertyName', 'Fandom article ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6744'), ('propertyName', 'FragDenStaat public body slug')]
# [('property', 'http://www.wikidata.org/prop/direct/P7502'), ('propertyName', 'Golden ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7888'), ('propertyName', 'merged into')]
# [('property', 'http://www.wikidata.org/prop/direct/P2259'), ('propertyName', 'mobile network code')]
# [('property', 'http://www.wikidata.org/prop/direct/P4015'), ('propertyName', 'Vimeo identifier')]
# [('property', 'http://www.wikidata.org/prop/direct/P8464'), ('propertyName', 'content partnership category')]
# [('property', 'http://www.wikidata.org/prop/direct/P115'), ('propertyName', 'home venue')]
# [('property', 'http://www.wikidata.org/prop/direct/P118'), ('propertyName', 'league')]
# [('property', 'http://www.wikidata.org/prop/direct/P123'), ('propertyName', 'publisher')]
# [('property', 'http://www.wikidata.org/prop/direct/P126'), ('propertyName', 'maintained by')]
# [('property', 'http://www.wikidata.org/prop/direct/P1687'), ('propertyName', 'Wikidata property')]
# [('property', 'http://www.wikidata.org/prop/direct/P1695'), ('propertyName', 'NLP ID (unique)')]
# [('property', 'http://www.wikidata.org/prop/direct/P178'), ('propertyName', 'developer')]
# [('property', 'http://www.wikidata.org/prop/direct/P199'), ('propertyName', 'business division')]
# [('property', 'http://www.wikidata.org/prop/direct/P2538'), ('propertyName', 'Nationalmuseum Sweden actor ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P286'), ('propertyName', 'head coach')]
# [('property', 'http://www.wikidata.org/prop/direct/P2924'), ('propertyName', 'Great Russian Encyclopedia Online ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P358'), ('propertyName', 'discography')]
# [('property', 'http://www.wikidata.org/prop/direct/P3789'), ('propertyName', 'Telegram username')]
# [('property', 'http://www.wikidata.org/prop/direct/P527'), ('propertyName', 'has part')]
# [('property', 'http://www.wikidata.org/prop/direct/P6181'), ('propertyName', 'Disney A to Z ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6413'), ('propertyName', 'JORFSearch organization ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6683'), ('propertyName', 'Alexander Turnbull Library ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7014'), ('propertyName', 'terms of service URL')]
# [('property', 'http://www.wikidata.org/prop/direct/P7632'), ('propertyName', 'MPPDA Digital Archive organisation ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7818'), ('propertyName', 'French Vikidia ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P800'), ('propertyName', 'notable work')]
# [('property', 'http://www.wikidata.org/prop/direct/P8496'), ('propertyName', 'Archive Site Trinity College Cambridge ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P9242'), ('propertyName', 'Whiskybase distillery ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P9318'), ('propertyName', 'Ávvir topic ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P9322'), ('propertyName', 'SVKKL authority ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4167'), ('propertyName', 'Dagens Næringsliv topic ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P634'), ('propertyName', 'captain')]
# [('property', 'http://www.wikidata.org/prop/direct/P6869'), ('propertyName', 'Hoopla publisher ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1297'), ('propertyName', 'IRS Employer Identification Number')]
# [('property', 'http://www.wikidata.org/prop/direct/P4861'), ('propertyName', 'Charity Navigator ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2531'), ('propertyName', 'Box Office Mojo studio ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4756'), ('propertyName', 'V Live channel ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6427'), ('propertyName', 'trading name')]
# [('property', 'http://www.wikidata.org/prop/direct/P2133'), ('propertyName', 'total debt')]
# [('property', 'http://www.wikidata.org/prop/direct/P3125'), ('propertyName', 'EDRPOU code')]
# [('property', 'http://www.wikidata.org/prop/direct/P2619'), ('propertyName', 'Hungarian company ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1368'), ('propertyName', 'LNB ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1842'), ('propertyName', 'Global Anabaptist Mennonite Encyclopedia Online ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1955'), ('propertyName', 'Discogs label ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P279'), ('propertyName', 'subclass of')]
# [('property', 'http://www.wikidata.org/prop/direct/P2959'), ('propertyName', 'permanent duplicated item')]
# [('property', 'http://www.wikidata.org/prop/direct/P3106'), ('propertyName', 'Guardian topic ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3348'), ('propertyName', 'National Library of Greece ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4081'), ('propertyName', 'BHL creator ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P460'), ('propertyName', 'said to be the same as')]
# [('property', 'http://www.wikidata.org/prop/direct/P5337'), ('propertyName', 'Google News topics ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5395'), ('propertyName', 'Canadian Encyclopedia article ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6058'), ('propertyName', 'Larousse ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6131'), ('propertyName', 'Soccerway team ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6364'), ('propertyName', 'official color(s)')]
# [('property', 'http://www.wikidata.org/prop/direct/P6404'), ('propertyName', "Treccani's Dizionario di Storia ID")]
# [('property', 'http://www.wikidata.org/prop/direct/P669'), ('propertyName', 'located on street')]
# [('property', 'http://www.wikidata.org/prop/direct/P6821'), ('propertyName', 'Uppsala University Alvin ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7223'), ('propertyName', 'Transfermarkt team ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7280'), ('propertyName', 'PlaymakerStats.com team ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7287'), ('propertyName', 'WorldFootball.net team ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7314'), ('propertyName', 'TDV İslam Ansiklopedisi ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7361'), ('propertyName', 'UEFA team ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7854'), ('propertyName', 'EU-Football.info club ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P94'), ('propertyName', 'coat of arms image')]
# [('property', 'http://www.wikidata.org/prop/direct/P9495'), ('propertyName', 'National Historical Museums of Sweden agent ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3220'), ('propertyName', 'KvK company ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P458'), ('propertyName', 'IMO ship number')]
# [('property', 'http://www.wikidata.org/prop/direct/P1810'), ('propertyName', 'named as')]
# [('property', 'http://www.wikidata.org/prop/direct/P8147'), ('propertyName', 'National-Football-Teams.com club ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2663'), ('propertyName', 'common equity tier 1 capital ratio (CETI)')]
# [('property', 'http://www.wikidata.org/prop/direct/P8939'), ('propertyName', 'Google Play developer slug')]
# [('property', 'http://www.wikidata.org/prop/direct/P1005'), ('propertyName', 'Portuguese National Library ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1114'), ('propertyName', 'quantity')]
# [('property', 'http://www.wikidata.org/prop/direct/P1411'), ('propertyName', 'nominated for')]
# [('property', 'http://www.wikidata.org/prop/direct/P1472'), ('propertyName', 'Commons Creator page')]
# [('property', 'http://www.wikidata.org/prop/direct/P1795'), ('propertyName', 'Smithsonian American Art Museum person/institution ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1833'), ('propertyName', 'number of registered users/contributors')]
# [('property', 'http://www.wikidata.org/prop/direct/P1943'), ('propertyName', 'location map')]
# [('property', 'http://www.wikidata.org/prop/direct/P3721'), ('propertyName', 'public key fingerprint')]
# [('property', 'http://www.wikidata.org/prop/direct/P4104'), ('propertyName', 'Carnegie Hall agent ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P434'), ('propertyName', 'MusicBrainz artist ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5019'), ('propertyName', 'Brockhaus Enzyklopädie online ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P503'), ('propertyName', 'ISO standard')]
# [('property', 'http://www.wikidata.org/prop/direct/P6016'), ('propertyName', 'Tennessee Encyclopedia ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7695'), ('propertyName', 'e-WV: The West Virginia Encyclopedia ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7865'), ('propertyName', 'CoBiS author ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P9368'), ('propertyName', 'CNA topic ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P9650'), ('propertyName', 'Internet Game Database company ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1327'), ('propertyName', 'partner in business or sport')]
# [('property', 'http://www.wikidata.org/prop/direct/P3349'), ('propertyName', 'designed to carry')]
# [('property', 'http://www.wikidata.org/prop/direct/P4228'), ('propertyName', 'Encyclopedia of Australian Science ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2472'), ('propertyName', 'ACMA Radiocommunications Client Number')]
# [('property', 'http://www.wikidata.org/prop/direct/P4103'), ('propertyName', 'assets under management')]
# [('property', 'http://www.wikidata.org/prop/direct/P2771'), ('propertyName', 'D-U-N-S number')]
# [('property', 'http://www.wikidata.org/prop/direct/P3377'), ('propertyName', 'Bloomberg company ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1362'), ('propertyName', 'Theaterlexikon der Schweiz ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1430'), ('propertyName', 'OpenPlaques subject ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2716'), ('propertyName', 'collage image')]
# [('property', 'http://www.wikidata.org/prop/direct/P3876'), ('propertyName', 'category for alumni of educational institution')]
# [('property', 'http://www.wikidata.org/prop/direct/P4073'), ('propertyName', 'Fandom wiki ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P580'), ('propertyName', 'start time')]
# [('property', 'http://www.wikidata.org/prop/direct/P9549'), ('propertyName', 'official podcast')]
# [('property', 'http://www.wikidata.org/prop/direct/P1928'), ('propertyName', 'Vaccine Ontology ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2740'), ('propertyName', 'ResearchGate institute ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5768'), ('propertyName', 'Osservatorio culturale del Cantone Ticino ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6370'), ('propertyName', 'REDIZO')]
# [('property', 'http://www.wikidata.org/prop/direct/P3276'), ('propertyName', 'Angel List ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1017'), ('propertyName', 'Vatican Library ID (former scheme)')]
# [('property', 'http://www.wikidata.org/prop/direct/P242'), ('propertyName', 'locator map image')]
# [('property', 'http://www.wikidata.org/prop/direct/P2741'), ('propertyName', 'Tate artist ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5513'), ('propertyName', "Enciclopèdia de l'Esport Català ID")]
# [('property', 'http://www.wikidata.org/prop/direct/P6150'), ('propertyName', 'Academy Awards Database nominee ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6900'), ('propertyName', 'NicoNicoPedia ID')]
# ...
# [('property', 'http://www.wikidata.org/prop/direct/P8246'), ('propertyName', 'Natural Atlas ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P8868'), ('propertyName', 'AAA hotel ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1286'), ('propertyName', 'Munzinger Pop ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P8894'), ('propertyName', 'BG EIK')]
# [('property', 'http://www.wikidata.org/prop/direct/P7022'), ('propertyName', 'Australian Suppliers Directory ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2081'), ('propertyName', 'BLDAM object ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3877'), ('propertyName', 'HappyCow restaurant ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4031'), ('propertyName', 'Hungarian NGO ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P9585'), ('propertyName', 'Lexikon der österreichischen Provenienzforschung ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2957'), ('propertyName', 'throughput')]
# [('property', 'http://www.wikidata.org/prop/direct/P3188'), ('propertyName', 'Nobel prize ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P8024'), ('propertyName', 'Nobel Laureate API ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P8104'), ('propertyName', 'Paperity journal ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P8351'), ('propertyName', 'vglist video game ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1893'), ('propertyName', 'OpenPlaques plaque ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2651'), ('propertyName', 'CRICOS Provider Code')]
# [('property', 'http://www.wikidata.org/prop/direct/P8182'), ('propertyName', 'South African Company Registration Number')]
# [('property', 'http://www.wikidata.org/prop/direct/P2437'), ('propertyName', 'number of seasons')]
# [('property', 'http://www.wikidata.org/prop/direct/P3758'), ('propertyName', 'DOCOMOMO Ibérico ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1163'), ('propertyName', 'media type')]
# [('property', 'http://www.wikidata.org/prop/direct/P16'), ('propertyName', 'highway system')]
# [('property', 'http://www.wikidata.org/prop/direct/P4535'), ('propertyName', 'EUTA theatre ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5368'), ('propertyName', 'National Gallery of Canada artist ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P14'), ('propertyName', 'traffic sign')]
# [('property', 'http://www.wikidata.org/prop/direct/P7242'), ('propertyName', 'Laws & Regulations Database of the Republic of China ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1753'), ('propertyName', 'list related to category')]
# [('property', 'http://www.wikidata.org/prop/direct/P4249'), ('propertyName', 'Vincoli in Rete ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2700'), ('propertyName', 'protocol')]
# [('property', 'http://www.wikidata.org/prop/direct/P4610'), ('propertyName', 'ARTIC artwork ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6621'), ('propertyName', 'Le Figaro tag ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7467'), ('propertyName', 'Broadway Photographs person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P8577'), ('propertyName', 'ICP artist ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6949'), ('propertyName', 'announcement date')]
# [('property', 'http://www.wikidata.org/prop/direct/P8603'), ('propertyName', 'Istrapedia ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P8576'), ('propertyName', 'Hrvatska tehnička enciklopedija ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1104'), ('propertyName', 'number of pages')]
# [('property', 'http://www.wikidata.org/prop/direct/P8669'), ('propertyName', 'Encyclopaedia Beliana ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P957'), ('propertyName', 'ISBN-10')]
# [('property', 'http://www.wikidata.org/prop/direct/P2210'), ('propertyName', 'relative to')]
# [('property', 'http://www.wikidata.org/prop/direct/P6291'), ('propertyName', 'advertises')]
# [('property', 'http://www.wikidata.org/prop/direct/P9148'), ('propertyName', 'Saxony-Anhalt cultural heritage object ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P20'), ('propertyName', 'place of death')]
# [('property', 'http://www.wikidata.org/prop/direct/P1891'), ('propertyName', 'signatory')]
# [('property', 'http://www.wikidata.org/prop/direct/P9407'), ('propertyName', 'Polignosi ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6697'), ('propertyName', 'Football Money League rank')]
# [('property', 'http://www.wikidata.org/prop/direct/P609'), ('propertyName', 'terminus location')]
# [('property', 'http://www.wikidata.org/prop/direct/P2308'), ('propertyName', 'class')]
# [('property', 'http://www.wikidata.org/prop/direct/P7618'), ('propertyName', 'Virginia Landmarks Register ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2872'), ('propertyName', 'visitor centre')]
# [('property', 'http://www.wikidata.org/prop/direct/P2658'), ('propertyName', 'Scoville grade')]
# [('property', 'http://www.wikidata.org/prop/direct/P1691'), ('propertyName', 'operations and procedures key (OPS)')]
# [('property', 'http://www.wikidata.org/prop/direct/P7688'), ('propertyName', 'Mississippi Encyclopedia ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1407'), ('propertyName', 'MusicBrainz series ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2361'), ('propertyName', 'online service')]
# [('property', 'http://www.wikidata.org/prop/direct/P3607'), ('propertyName', 'Booking.com hotel ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P301'), ('propertyName', "category's main topic")]
# [('property', 'http://www.wikidata.org/prop/direct/P7591'), ('propertyName', 'VideoGameGeek game ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2209'), ('propertyName', 'SourceForge project')]
# [('property', 'http://www.wikidata.org/prop/direct/P3152'), ('propertyName', 'Findsmiley ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5308'), ('propertyName', 'Dictionary of Scottish Architects ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4529'), ('propertyName', 'Douban film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P9827'), ('propertyName', 'GSSO ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P734'), ('propertyName', 'family name')]
# [('property', 'http://www.wikidata.org/prop/direct/P2580'), ('propertyName', 'Baltisches Biographisches Lexikon digital ID (former scheme)')]
# [('property', 'http://www.wikidata.org/prop/direct/P2886'), ('propertyName', 'Shakeosphere person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7445'), ('propertyName', 'Basis Wien person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P828'), ('propertyName', 'has cause')]
# [('property', 'http://www.wikidata.org/prop/direct/P1393'), ('propertyName', 'proxy')]
# [('property', 'http://www.wikidata.org/prop/direct/P6989'), ('propertyName', 'Hungarian National Namespace organisation ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6582'), ('propertyName', 'Dutch Instrument Makers ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3052'), ('propertyName', 'Bloomberg person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2093'), ('propertyName', 'author name string')]
# [('property', 'http://www.wikidata.org/prop/direct/P4327'), ('propertyName', 'BHL bibliography ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P9101'), ('propertyName', 'Discord username')]
# [('property', 'http://www.wikidata.org/prop/direct/P1707'), ('propertyName', 'DAAO ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1584'), ('propertyName', 'Pleiades ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3200'), ('propertyName', 'Northern Ireland charity number')]
# [('property', 'http://www.wikidata.org/prop/direct/P7764'), ('propertyName', 'Archives Portal Europe ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4662'), ('propertyName', 'SAN archive conservator ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1960'), ('propertyName', 'Google Scholar author ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P8708'), ('propertyName', 'Danish educational institution number')]
# [('property', 'http://www.wikidata.org/prop/direct/P1978'), ('propertyName', 'USDA NDB number')]
# [('property', 'http://www.wikidata.org/prop/direct/P5115'), ('propertyName', 'Directory of Open Access Journals ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1442'), ('propertyName', 'image of grave')]
# [('property', 'http://www.wikidata.org/prop/direct/P4088'), ('propertyName', 'Irish National Inventory of Architectural Heritage ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P462'), ('propertyName', 'color')]
# [('property', 'http://www.wikidata.org/prop/direct/P8957'), ('propertyName', 'GS1 GPC code')]
# [('property', 'http://www.wikidata.org/prop/direct/P2167'), ('propertyName', 'UNSPSC Code')]
# [('property', 'http://www.wikidata.org/prop/direct/P4891'), ('propertyName', 'Patrons de France ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5282'), ('propertyName', 'ground level 360 degree view')]
# [('property', 'http://www.wikidata.org/prop/direct/P3056'), ('propertyName', 'TCM Movie Database person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2432'), ('propertyName', 'J. Paul Getty Museum artist id')]
# [('property', 'http://www.wikidata.org/prop/direct/P272'), ('propertyName', 'production company')]
# [('property', 'http://www.wikidata.org/prop/direct/P675'), ('propertyName', 'Google Books ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4835'), ('propertyName', 'TheTVDB.com series ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3318'), ('propertyName', 'Guía Digital del Patrimonio Cultural de Andalucía identifier')]
# [('property', 'http://www.wikidata.org/prop/direct/P8425'), ('propertyName', 'IAPH code')]
# [('property', 'http://www.wikidata.org/prop/direct/P3929'), ('propertyName', 'V&A item ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2025'), ('propertyName', 'Find A Grave cemetery ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1401'), ('propertyName', 'bug tracking system')]
# [('property', 'http://www.wikidata.org/prop/direct/P9194'), ('propertyName', 'LombardiaBeniCulturali archive producer organization ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1305'), ('propertyName', 'CTBUH Skyscraper Center building ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4357'), ('propertyName', 'Musikverket person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7783'), ('propertyName', 'J-GLOBAL ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7590'), ('propertyName', 'eBay username')]
# [('property', 'http://www.wikidata.org/prop/direct/P9487'), ('propertyName', 'GLEI RAL')]
# [('property', 'http://www.wikidata.org/prop/direct/P7296'), ('propertyName', 'Lower Austrian Museum ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3424'), ('propertyName', 'Polish cultural heritage register number')]
# [('property', 'http://www.wikidata.org/prop/direct/P9240'), ('propertyName', 'Encyclopedia of Seventh-day Adventists ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P664'), ('propertyName', 'organizer')]
# [('property', 'http://www.wikidata.org/prop/direct/P473'), ('propertyName', 'local dialing code')]
# [('property', 'http://www.wikidata.org/prop/direct/P971'), ('propertyName', 'category combines topics')]
# [('property', 'http://www.wikidata.org/prop/direct/P6195'), ('propertyName', 'funding scheme')]
# [('property', 'http://www.wikidata.org/prop/direct/P3087'), ('propertyName', 'fiscal/tax revenue')]
# [('property', 'http://www.wikidata.org/prop/direct/P8638'), ('propertyName', 'British and Irish Furniture Makers Online ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1659'), ('propertyName', 'see also')]
# [('property', 'http://www.wikidata.org/prop/direct/P8108'), ('propertyName', 'Papers Past ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1595'), ('propertyName', 'charge')]
# [('property', 'http://www.wikidata.org/prop/direct/P2505'), ('propertyName', 'carries')]
# [('property', 'http://www.wikidata.org/prop/direct/P1876'), ('propertyName', 'vehicle')]
# [('property', 'http://www.wikidata.org/prop/direct/P2795'), ('propertyName', 'directions')]
# [('property', 'http://www.wikidata.org/prop/direct/P1427'), ('propertyName', 'start point')]
# [('property', 'http://www.wikidata.org/prop/direct/P1444'), ('propertyName', 'destination point')]
# [('property', 'http://www.wikidata.org/prop/direct/P3293'), ('propertyName', 'BALaT object ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1741'), ('propertyName', 'GTAA ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1600'), ('propertyName', 'Inventari del Patrimoni Arquitectònic de Catalunya code')]
# [('property', 'http://www.wikidata.org/prop/direct/P7429'), ('propertyName', 'Bundle ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P102'), ('propertyName', 'member of political party')]
# [('property', 'http://www.wikidata.org/prop/direct/P3970'), ('propertyName', 'channel number')]
# [('property', 'http://www.wikidata.org/prop/direct/P2175'), ('propertyName', 'medical condition treated')]
# [('property', 'http://www.wikidata.org/prop/direct/P4793'), ('propertyName', 'identifiers.org prefix')]
# [('property', 'http://www.wikidata.org/prop/direct/P1392'), ('propertyName', 'ComicBookDB Creator ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3138'), ('propertyName', 'OFDb film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P606'), ('propertyName', 'first flight')]
# [('property', 'http://www.wikidata.org/prop/direct/P5760'), ('propertyName', 'Petit Futé site ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6277'), ('propertyName', 'Objectif Gard topic ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6190'), ('propertyName', 'NSW State Archives and Records Authority Agency ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5252'), ('propertyName', 'winter view')]
# [('property', 'http://www.wikidata.org/prop/direct/P3026'), ('propertyName', 'closed on')]
# [('property', 'http://www.wikidata.org/prop/direct/P3914'), ('propertyName', 'GuideStar Israel organization ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6721'), ('propertyName', 'K10plus PPN ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P9070'), ('propertyName', 'Internet Encyclopedia of Ukraine ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5930'), ('propertyName', 'Open Food Facts ingredient ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3284'), ('propertyName', 'Yahoo! Japan Talent Database ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4738'), ('propertyName', 'Yale Center for British Art artwork ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P9096'), ('propertyName', 'Malpedia ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7900'), ('propertyName', 'Denkmalatlas Niedersachsen Objekt-ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P8357'), ('propertyName', 'SIUSA archive producer organization ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4625'), ('propertyName', 'Museum of Fine Arts, Boston object ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5400'), ('propertyName', 'GeoNLP ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1034'), ('propertyName', 'main food source')]
# [('property', 'http://www.wikidata.org/prop/direct/P7662'), ('propertyName', 'Scilit journal ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7324'), ('propertyName', 'iHeartRadio podcast ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4818'), ('propertyName', 'Panoptikum podcast ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1184'), ('propertyName', 'Handle ID')]
# 1659

# %%
#let's try instead to identify properties related only to companies in us, uk, canada
q = f"""
select distinct ?property ?propertyName where{{
# ?b wdt:P31 wd:Q4830453 .
# ?b ?property ?predicate .
# ?b wdt:P17 ?country .
filter(?country in (wd:Q16, wd:Q145, wd:Q30))
# ?property <http://schema.org/name> ?propertyName .
}}
"""
run_query(q)
# Out:
# [('property', 'http://www.wikidata.org/prop/direct/P2751'), ('propertyName', 'Roller Coaster Database ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1056'), ('propertyName', 'product or material produced')]
# [('property', 'http://www.wikidata.org/prop/direct/P112'), ('propertyName', 'founded by')]
# [('property', 'http://www.wikidata.org/prop/direct/P1128'), ('propertyName', 'employees')]
# [('property', 'http://www.wikidata.org/prop/direct/P127'), ('propertyName', 'owned by')]
# [('property', 'http://www.wikidata.org/prop/direct/P1454'), ('propertyName', 'legal form')]
# [('property', 'http://www.wikidata.org/prop/direct/P154'), ('propertyName', 'logo image')]
# [('property', 'http://www.wikidata.org/prop/direct/P159'), ('propertyName', 'headquarters location')]
# [('property', 'http://www.wikidata.org/prop/direct/P17'), ('propertyName', 'country')]
# [('property', 'http://www.wikidata.org/prop/direct/P18'), ('propertyName', 'image')]
# [('property', 'http://www.wikidata.org/prop/direct/P2002'), ('propertyName', 'Twitter username')]
# [('property', 'http://www.wikidata.org/prop/direct/P2003'), ('propertyName', 'Instagram username')]
# [('property', 'http://www.wikidata.org/prop/direct/P2013'), ('propertyName', 'Facebook ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2088'), ('propertyName', 'Crunchbase organization ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P213'), ('propertyName', 'ISNI')]
# [('property', 'http://www.wikidata.org/prop/direct/P214'), ('propertyName', 'VIAF ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P227'), ('propertyName', 'GND ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2397'), ('propertyName', 'YouTube channel ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2427'), ('propertyName', 'GRID ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P244'), ('propertyName', 'Library of Congress authority ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P31'), ('propertyName', 'instance of')]
# [('property', 'http://www.wikidata.org/prop/direct/P3153'), ('propertyName', 'Crossref funder ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3417'), ('propertyName', 'Quora topic ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P345'), ('propertyName', 'IMDb ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3500'), ('propertyName', 'Ringgold ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P355'), ('propertyName', 'subsidiary')]
# [('property', 'http://www.wikidata.org/prop/direct/P361'), ('propertyName', 'part of')]
# [('property', 'http://www.wikidata.org/prop/direct/P373'), ('propertyName', 'Commons category')]
# [('property', 'http://www.wikidata.org/prop/direct/P41'), ('propertyName', 'flag image')]
# [('property', 'http://www.wikidata.org/prop/direct/P414'), ('propertyName', 'stock exchange')]
# [('property', 'http://www.wikidata.org/prop/direct/P452'), ('propertyName', 'industry')]
# [('property', 'http://www.wikidata.org/prop/direct/P4839'), ('propertyName', 'Wolfram Language entity code')]
# [('property', 'http://www.wikidata.org/prop/direct/P571'), ('propertyName', 'inception')]
# [('property', 'http://www.wikidata.org/prop/direct/P576'), ('propertyName', 'dissolved, abolished or demolished date')]
# [('property', 'http://www.wikidata.org/prop/direct/P6366'), ('propertyName', 'Microsoft Academic ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P641'), ('propertyName', 'sport')]
# [('property', 'http://www.wikidata.org/prop/direct/P646'), ('propertyName', 'Freebase ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6773'), ('propertyName', 'HAL structure ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6782'), ('propertyName', 'ROR ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P740'), ('propertyName', 'location of formation')]
# [('property', 'http://www.wikidata.org/prop/direct/P749'), ('propertyName', 'parent organization')]
# [('property', 'http://www.wikidata.org/prop/direct/P7859'), ('propertyName', 'WorldCat Identities ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P8253'), ('propertyName', 'OSM Name Suggestion Index identifier')]
# [('property', 'http://www.wikidata.org/prop/direct/P856'), ('propertyName', 'official website')]
# [('property', 'http://www.wikidata.org/prop/direct/P8687'), ('propertyName', 'social media followers')]
# [('property', 'http://www.wikidata.org/prop/direct/P910'), ('propertyName', "topic's main category")]
# [('property', 'http://www.wikidata.org/prop/direct/P946'), ('propertyName', 'ISIN')]
# [('property', 'http://www.wikidata.org/prop/direct/P6617'), ('propertyName', 'RoMEO publisher ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7403'), ('propertyName', 'Publons publisher ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P8562'), ('propertyName', 'JSTOR publisher ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1015'), ('propertyName', 'NORAF ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1017'), ('propertyName', 'Vatican Library ID (former scheme)')]
# [('property', 'http://www.wikidata.org/prop/direct/P1037'), ('propertyName', 'director / manager')]
# [('property', 'http://www.wikidata.org/prop/direct/P1278'), ('propertyName', 'Legal Entity Identifier')]
# [('property', 'http://www.wikidata.org/prop/direct/P1296'), ('propertyName', 'Gran Enciclopèdia Catalana ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1299'), ('propertyName', 'depicted by')]
# [('property', 'http://www.wikidata.org/prop/direct/P131'), ('propertyName', 'located in the administrative territorial entity')]
# [('property', 'http://www.wikidata.org/prop/direct/P1315'), ('propertyName', 'NLA Trove ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1320'), ('propertyName', 'OpenCorporates ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1329'), ('propertyName', 'phone number')]
# [('property', 'http://www.wikidata.org/prop/direct/P1343'), ('propertyName', 'described by source')]
# [('property', 'http://www.wikidata.org/prop/direct/P1344'), ('propertyName', 'participant in')]
# [('property', 'http://www.wikidata.org/prop/direct/P1365'), ('propertyName', 'replaces')]
# [('property', 'http://www.wikidata.org/prop/direct/P137'), ('propertyName', 'operator')]
# [('property', 'http://www.wikidata.org/prop/direct/P1417'), ('propertyName', 'Encyclopædia Britannica Online ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1430'), ('propertyName', 'OpenPlaques subject ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1448'), ('propertyName', 'official name')]
# [('property', 'http://www.wikidata.org/prop/direct/P155'), ('propertyName', 'follows')]
# [('property', 'http://www.wikidata.org/prop/direct/P1552'), ('propertyName', 'has quality')]
# [('property', 'http://www.wikidata.org/prop/direct/P156'), ('propertyName', 'followed by')]
# [('property', 'http://www.wikidata.org/prop/direct/P169'), ('propertyName', 'chief executive officer')]
# [('property', 'http://www.wikidata.org/prop/direct/P1705'), ('propertyName', 'native label')]
# [('property', 'http://www.wikidata.org/prop/direct/P1711'), ('propertyName', 'British Museum person or institution ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1816'), ('propertyName', 'National Portrait Gallery (London) person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1830'), ('propertyName', 'owner of')]
# [('property', 'http://www.wikidata.org/prop/direct/P1889'), ('propertyName', 'different from')]
# [('property', 'http://www.wikidata.org/prop/direct/P1955'), ('propertyName', 'Discogs label ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2037'), ('propertyName', 'GitHub username')]
# [('property', 'http://www.wikidata.org/prop/direct/P2139'), ('propertyName', 'total revenue')]
# [('property', 'http://www.wikidata.org/prop/direct/P2163'), ('propertyName', 'FAST ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2561'), ('propertyName', 'name')]
# [('property', 'http://www.wikidata.org/prop/direct/P2657'), ('propertyName', 'EU Transparency Register ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2666'), ('propertyName', 'Datahub page')]
# [('property', 'http://www.wikidata.org/prop/direct/P2671'), ('propertyName', 'Google Knowledge Graph ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P268'), ('propertyName', 'Bibliothèque nationale de France ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P269'), ('propertyName', 'IdRef ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2741'), ('propertyName', 'Tate artist ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P279'), ('propertyName', 'subclass of')]
# [('property', 'http://www.wikidata.org/prop/direct/P2900'), ('propertyName', 'fax number')]
# [('property', 'http://www.wikidata.org/prop/direct/P2924'), ('propertyName', 'Great Russian Encyclopedia Online ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3029'), ('propertyName', 'UK National Archives ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3065'), ('propertyName', 'RERO ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3106'), ('propertyName', 'Guardian topic ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3222'), ('propertyName', 'NE.se ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3347'), ('propertyName', 'PermID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3393'), ('propertyName', 'LittleSis organization ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3430'), ('propertyName', 'SNAC ARK ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3544'), ('propertyName', 'Te Papa agent ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3603'), ('propertyName', 'Minneapolis Institute of Art constituent ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3608'), ('propertyName', 'EU VAT number')]
# [('property', 'http://www.wikidata.org/prop/direct/P366'), ('propertyName', 'use')]
# [('property', 'http://www.wikidata.org/prop/direct/P3761'), ('propertyName', 'IPv4 routing prefix')]
# [('property', 'http://www.wikidata.org/prop/direct/P3794'), ('propertyName', 'Dictionary of Sydney ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4264'), ('propertyName', 'LinkedIn company ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4293'), ('propertyName', 'PM20 folder ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4527'), ('propertyName', 'UK Parliament thesaurus ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4553'), ('propertyName', 'RA Collections ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P463'), ('propertyName', 'member of')]
# [('property', 'http://www.wikidata.org/prop/direct/P4773'), ('propertyName', 'MobyGames company ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4808'), ('propertyName', 'Royal Academy new identifier')]
# [('property', 'http://www.wikidata.org/prop/direct/P485'), ('propertyName', 'archives at')]
# [('property', 'http://www.wikidata.org/prop/direct/P488'), ('propertyName', 'chairperson')]
# [('property', 'http://www.wikidata.org/prop/direct/P495'), ('propertyName', 'country of origin')]
# [('property', 'http://www.wikidata.org/prop/direct/P5008'), ('propertyName', 'on focus list of Wikimedia project')]
# [('property', 'http://www.wikidata.org/prop/direct/P5508'), ('propertyName', 'archINFORM person or group ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5785'), ('propertyName', 'EU Research participant ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6262'), ('propertyName', 'Fandom article ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6379'), ('propertyName', 'has works in the collection')]
# [('property', 'http://www.wikidata.org/prop/direct/P650'), ('propertyName', 'RKDartists ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P669'), ('propertyName', 'located on street')]
# [('property', 'http://www.wikidata.org/prop/direct/P6706'), ('propertyName', 'De Agostini ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P691'), ('propertyName', 'NKCR AUT ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7128'), ('propertyName', 'Archives Directory for the History of Collecting in America ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7632'), ('propertyName', 'MPPDA Digital Archive organisation ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7763'), ('propertyName', 'copyright status as a creator')]
# [('property', 'http://www.wikidata.org/prop/direct/P7936'), ('propertyName', 'business model')]
# [('property', 'http://www.wikidata.org/prop/direct/P7959'), ('propertyName', 'historic county')]
# [('property', 'http://www.wikidata.org/prop/direct/P8034'), ('propertyName', 'Vatican Library VcBA ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P8317'), ('propertyName', 'Philadelphia Museum of Art entity ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P8406'), ('propertyName', 'Grove Art Online ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P8496'), ('propertyName', 'Archive Site Trinity College Cambridge ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P8605'), ('propertyName', 'Linked Open Data Cloud identifier')]
# [('property', 'http://www.wikidata.org/prop/direct/P88'), ('propertyName', 'commissioned by')]
# [('property', 'http://www.wikidata.org/prop/direct/P949'), ('propertyName', 'National Library of Israel ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P966'), ('propertyName', 'MusicBrainz label ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P973'), ('propertyName', 'described at URL')]
# [('property', 'http://www.wikidata.org/prop/direct/P9756'), ('propertyName', 'Schoenberg Database of Manuscripts name ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3035'), ('propertyName', 'ISBN publisher prefix')]
# [('property', 'http://www.wikidata.org/prop/direct/P6375'), ('propertyName', 'street address')]
# [('property', 'http://www.wikidata.org/prop/direct/P1662'), ('propertyName', 'DOI prefix')]
# [('property', 'http://www.wikidata.org/prop/direct/P2622'), ('propertyName', 'Companies House company ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3642'), ('propertyName', 'ARCHON code')]
# [('property', 'http://www.wikidata.org/prop/direct/P7769'), ('propertyName', 'Australian National Maritime Museum person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3679'), ('propertyName', 'stock market index')]
# [('property', 'http://www.wikidata.org/prop/direct/P2531'), ('propertyName', 'Box Office Mojo studio ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7438'), ('propertyName', 'FantLab publisher ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5062'), ('propertyName', 'DOAB publisher ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6427'), ('propertyName', 'trading name')]
# [('property', 'http://www.wikidata.org/prop/direct/P3447'), ('propertyName', 'mirrors data from')]
# [('property', 'http://www.wikidata.org/prop/direct/P6202'), ('propertyName', 'Geolex ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3098'), ('propertyName', 'ClinicalTrials.gov ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P101'), ('propertyName', 'field of work')]
# [('property', 'http://www.wikidata.org/prop/direct/P1167'), ('propertyName', 'USB vendor ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1207'), ('propertyName', 'NUKAT ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1273'), ('propertyName', 'CANTIC ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1366'), ('propertyName', 'replaced by')]
# [('property', 'http://www.wikidata.org/prop/direct/P138'), ('propertyName', 'named after')]
# [('property', 'http://www.wikidata.org/prop/direct/P1581'), ('propertyName', 'official blog')]
# [('property', 'http://www.wikidata.org/prop/direct/P163'), ('propertyName', 'flag')]
# [('property', 'http://www.wikidata.org/prop/direct/P166'), ('propertyName', 'award received')]
# [('property', 'http://www.wikidata.org/prop/direct/P1661'), ('propertyName', 'Alexa rank')]
# [('property', 'http://www.wikidata.org/prop/direct/P1670'), ('propertyName', 'Canadiana Authorities ID (former scheme)')]
# [('property', 'http://www.wikidata.org/prop/direct/P176'), ('propertyName', 'manufacturer')]
# [('property', 'http://www.wikidata.org/prop/direct/P1771'), ('propertyName', 'Integrated Postsecondary Education Data System ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1789'), ('propertyName', 'chief operating officer')]
# [('property', 'http://www.wikidata.org/prop/direct/P1813'), ('propertyName', 'short name')]
# [('property', 'http://www.wikidata.org/prop/direct/P2011'), ('propertyName', 'Cooper-Hewitt Person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2174'), ('propertyName', 'Museum of Modern Art artist ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2295'), ('propertyName', 'net profit')]
# [('property', 'http://www.wikidata.org/prop/direct/P2403'), ('propertyName', 'total assets')]
# [('property', 'http://www.wikidata.org/prop/direct/P2581'), ('propertyName', 'BabelNet ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P271'), ('propertyName', 'CiNii author ID (books)')]
# [('property', 'http://www.wikidata.org/prop/direct/P276'), ('propertyName', 'location')]
# [('property', 'http://www.wikidata.org/prop/direct/P281'), ('propertyName', 'postal code')]
# [('property', 'http://www.wikidata.org/prop/direct/P2847'), ('propertyName', 'Google+ ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3225'), ('propertyName', 'Corporate Number (Japan)')]
# [('property', 'http://www.wikidata.org/prop/direct/P3362'), ('propertyName', 'operating income')]
# [('property', 'http://www.wikidata.org/prop/direct/P3381'), ('propertyName', 'File Format Wiki page ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3553'), ('propertyName', 'Zhihu topic ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3749'), ('propertyName', 'Google Maps Customer ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3793'), ('propertyName', 'IPv6 routing prefix')]
# [('property', 'http://www.wikidata.org/prop/direct/P3836'), ('propertyName', 'Pinterest username')]
# [('property', 'http://www.wikidata.org/prop/direct/P3984'), ('propertyName', 'subreddit')]
# [('property', 'http://www.wikidata.org/prop/direct/P3987'), ('propertyName', 'SHARE Catalogue author ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4013'), ('propertyName', 'Giphy username')]
# [('property', 'http://www.wikidata.org/prop/direct/P421'), ('propertyName', 'located in time zone')]
# [('property', 'http://www.wikidata.org/prop/direct/P4486'), ('propertyName', 'Google Play developer ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4776'), ('propertyName', 'MAC Address Block Large ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6295'), ('propertyName', 'ARTIC artist ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7157'), ('propertyName', 'The Top Tens ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7306'), ('propertyName', 'Downdetector ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7901'), ('propertyName', 'Encyclopedia of Chicago ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P906'), ('propertyName', 'SELIBR ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P9152'), ('propertyName', 'CollectieGelderland creator ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P921'), ('propertyName', 'main subject')]
# [('property', 'http://www.wikidata.org/prop/direct/P2179'), ('propertyName', 'ACM Classification Code (2012)')]
# [('property', 'http://www.wikidata.org/prop/direct/P3242'), ('propertyName', 'SIC code')]
# [('property', 'http://www.wikidata.org/prop/direct/P5531'), ('propertyName', 'Central Index Key')]
# [('property', 'http://www.wikidata.org/prop/direct/P2014'), ('propertyName', 'Museum of Modern Art work ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2137'), ('propertyName', 'total equity')]
# [('property', 'http://www.wikidata.org/prop/direct/P4936'), ('propertyName', 'SFMOMA artist ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4691'), ('propertyName', 'OpenSecrets organization ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1951'), ('propertyName', 'investor')]
# [('property', 'http://www.wikidata.org/prop/direct/P2138'), ('propertyName', 'total liabilities')]
# [('property', 'http://www.wikidata.org/prop/direct/P249'), ('propertyName', 'ticker symbol')]
# [('property', 'http://www.wikidata.org/prop/direct/P8340'), ('propertyName', 'estimated value')]
# [('property', 'http://www.wikidata.org/prop/direct/P8939'), ('propertyName', 'Google Play developer slug')]
# [('property', 'http://www.wikidata.org/prop/direct/P7639'), ('propertyName', 'OverDrive publisher ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1114'), ('propertyName', 'quantity')]
# [('property', 'http://www.wikidata.org/prop/direct/P1424'), ('propertyName', "topic's main template")]
# [('property', 'http://www.wikidata.org/prop/direct/P1566'), ('propertyName', 'GeoNames ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1687'), ('propertyName', 'Wikidata property')]
# [('property', 'http://www.wikidata.org/prop/direct/P1833'), ('propertyName', 'number of registered users/contributors')]
# [('property', 'http://www.wikidata.org/prop/direct/P199'), ('propertyName', 'business division')]
# [('property', 'http://www.wikidata.org/prop/direct/P2226'), ('propertyName', 'market capitalization')]
# [('property', 'http://www.wikidata.org/prop/direct/P2541'), ('propertyName', 'operating area')]
# [('property', 'http://www.wikidata.org/prop/direct/P2627'), ('propertyName', 'ISO 9362 SWIFT/BIC code')]
# [('property', 'http://www.wikidata.org/prop/direct/P3221'), ('propertyName', 'New York Times topic ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3342'), ('propertyName', 'significant person')]
# [('property', 'http://www.wikidata.org/prop/direct/P349'), ('propertyName', 'National Diet Library ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3721'), ('propertyName', 'public key fingerprint')]
# [('property', 'http://www.wikidata.org/prop/direct/P3743'), ('propertyName', 'ITU/ISO/IEC object identifier')]
# [('property', 'http://www.wikidata.org/prop/direct/P407'), ('propertyName', 'language of work or name')]
# [('property', 'http://www.wikidata.org/prop/direct/P409'), ('propertyName', 'Libraries Australia ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4104'), ('propertyName', 'Carnegie Hall agent ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P503'), ('propertyName', 'ISO standard')]
# [('property', 'http://www.wikidata.org/prop/direct/P5260'), ('propertyName', 'App Store developer ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5337'), ('propertyName', 'Google News topics ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6016'), ('propertyName', 'Tennessee Encyclopedia ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6181'), ('propertyName', 'Disney A to Z ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6839'), ('propertyName', 'TV Tropes identifier')]
# [('property', 'http://www.wikidata.org/prop/direct/P7502'), ('propertyName', 'Golden ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7695'), ('propertyName', 'e-WV: The West Virginia Encyclopedia ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7818'), ('propertyName', 'French Vikidia ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P793'), ('propertyName', 'significant event')]
# [('property', 'http://www.wikidata.org/prop/direct/P8408'), ('propertyName', 'KBpedia ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P9242'), ('propertyName', 'Whiskybase distillery ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P935'), ('propertyName', 'Commons gallery')]
# [('property', 'http://www.wikidata.org/prop/direct/P9650'), ('propertyName', 'Internet Game Database company ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3349'), ('propertyName', 'designed to carry')]
# [('property', 'http://www.wikidata.org/prop/direct/P6160'), ('propertyName', 'BoardGameGeek game publisher ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6422'), ('propertyName', 'ManualsLib brand ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6869'), ('propertyName', 'Hoopla publisher ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7997'), ('propertyName', 'GRY-Online company ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1297'), ('propertyName', 'IRS Employer Identification Number')]
# [('property', 'http://www.wikidata.org/prop/direct/P4861'), ('propertyName', 'Charity Navigator ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P458'), ('propertyName', 'IMO ship number')]
# [('property', 'http://www.wikidata.org/prop/direct/P1810'), ('propertyName', 'named as')]
# [('property', 'http://www.wikidata.org/prop/direct/P2771'), ('propertyName', 'D-U-N-S number')]
# [('property', 'http://www.wikidata.org/prop/direct/P3377'), ('propertyName', 'Bloomberg company ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1239'), ('propertyName', 'ISFDB publisher ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3276'), ('propertyName', 'Angel List ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P242'), ('propertyName', 'locator map image')]
# [('property', 'http://www.wikidata.org/prop/direct/P2750'), ('propertyName', "Photographers' Identities Catalog ID")]
# [('property', 'http://www.wikidata.org/prop/direct/P3888'), ('propertyName', 'Boijmans artist ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4073'), ('propertyName', 'Fandom wiki ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4081'), ('propertyName', 'BHL creator ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P425'), ('propertyName', 'field of this occupation')]
# [('property', 'http://www.wikidata.org/prop/direct/P5905'), ('propertyName', 'Comic Vine ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6009'), ('propertyName', 'Techopedia ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6150'), ('propertyName', 'Academy Awards Database nominee ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P9549'), ('propertyName', 'official podcast')]
# [('property', 'http://www.wikidata.org/prop/direct/P9432'), ('propertyName', 'GCD publisher ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P9320'), ('propertyName', 'ComiXology publisher ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1932'), ('propertyName', 'stated as')]
# [('property', 'http://www.wikidata.org/prop/direct/P7755'), ('propertyName', 'ScreenScraper company ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P8860'), ('propertyName', 'Canada Business Number')]
# [('property', 'http://www.wikidata.org/prop/direct/P1269'), ('propertyName', 'facet of')]
# [('property', 'http://www.wikidata.org/prop/direct/P140'), ('propertyName', 'religion')]
# [('property', 'http://www.wikidata.org/prop/direct/P1695'), ('propertyName', 'NLP ID (unique)')]
# [('property', 'http://www.wikidata.org/prop/direct/P3348'), ('propertyName', 'National Library of Greece ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4204'), ('propertyName', 'The Times of India topic ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5395'), ('propertyName', 'Canadian Encyclopedia article ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7014'), ('propertyName', 'terms of service URL')]
# [('property', 'http://www.wikidata.org/prop/direct/P4573'), ('propertyName', 'Merchant Category Code')]
# [('property', 'http://www.wikidata.org/prop/direct/P7101'), ('propertyName', 'privacy policy URL')]
# [('property', 'http://www.wikidata.org/prop/direct/P7521'), ('propertyName', 'Gaming-History company ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P8501'), ('propertyName', 'Gateway to Research organisation ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3057'), ('propertyName', 'Charity Commission no.')]
# [('property', 'http://www.wikidata.org/prop/direct/P6182'), ('propertyName', 'GameFAQs company ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7570'), ('propertyName', 'OGDB company ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1712'), ('propertyName', 'Metacritic ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2650'), ('propertyName', 'interested in')]
# [('property', 'http://www.wikidata.org/prop/direct/P3320'), ('propertyName', 'board member')]
# [('property', 'http://www.wikidata.org/prop/direct/P3569'), ('propertyName', 'Cultureel Woordenboek ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4254'), ('propertyName', 'Bengali Banglapedia ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P434'), ('propertyName', 'MusicBrainz artist ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P527'), ('propertyName', 'has part')]
# [('property', 'http://www.wikidata.org/prop/direct/P6200'), ('propertyName', 'BBC News topic ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6683'), ('propertyName', 'Alexander Turnbull Library ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6802'), ('propertyName', 'related image')]
# [('property', 'http://www.wikidata.org/prop/direct/P7642'), ('propertyName', 'TheGamesDB publisher ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7708'), ('propertyName', 'SNESmusic.org company ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7886'), ('propertyName', 'Media Arts Database ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P800'), ('propertyName', 'notable work')]
# [('property', 'http://www.wikidata.org/prop/direct/P9402'), ('propertyName', 'GameSpot developer ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P950'), ('propertyName', 'Biblioteca Nacional de España ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P9629'), ('propertyName', 'Armeniapedia ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P121'), ('propertyName', 'item operated')]
# [('property', 'http://www.wikidata.org/prop/direct/P3074'), ('propertyName', "Grace's Guide ID")]
# [('property', 'http://www.wikidata.org/prop/direct/P7560'), ('propertyName', 'UVL company ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7634'), ('propertyName', 'TheGamesDB developer ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7784'), ('propertyName', 'LaunchBox Games Database developer ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7810'), ('propertyName', 'LaunchBox Games Database publisher ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P113'), ('propertyName', 'airline hub')]
# [('property', 'http://www.wikidata.org/prop/direct/P229'), ('propertyName', 'IATA airline designator')]
# [('property', 'http://www.wikidata.org/prop/direct/P2782'), ('propertyName', 'Models.com client ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3404'), ('propertyName', 'The Vogue List ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P432'), ('propertyName', 'callsign of airline')]
# [('property', 'http://www.wikidata.org/prop/direct/P7888'), ('propertyName', 'merged into')]
# [('property', 'http://www.wikidata.org/prop/direct/P3482'), ('propertyName', 'Europeana Fashion creator ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4103'), ('propertyName', 'assets under management')]
# [('property', 'http://www.wikidata.org/prop/direct/P8176'), ('propertyName', 'Itch.io developer profile')]
# [('property', 'http://www.wikidata.org/prop/direct/P2663'), ('propertyName', 'common equity tier 1 capital ratio (CETI)')]
# [('property', 'http://www.wikidata.org/prop/direct/P1019'), ('propertyName', 'web feed URL')]
# [('property', 'http://www.wikidata.org/prop/direct/P1368'), ('propertyName', 'LNB ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1451'), ('propertyName', 'motto text')]
# [('property', 'http://www.wikidata.org/prop/direct/P1619'), ('propertyName', 'date of official opening')]
# [('property', 'http://www.wikidata.org/prop/direct/P178'), ('propertyName', 'developer')]
# [('property', 'http://www.wikidata.org/prop/direct/P245'), ('propertyName', 'Union List of Artist Names ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3418'), ('propertyName', 'Google Play Store app ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3797'), ('propertyName', 'autonomous system number')]
# [('property', 'http://www.wikidata.org/prop/direct/P3861'), ('propertyName', 'App Store app ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3977'), ('propertyName', 'Songkick venue ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4290'), ('propertyName', 'official app')]
# [('property', 'http://www.wikidata.org/prop/direct/P4342'), ('propertyName', 'Store norske leksikon ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4354'), ('propertyName', 'search formatter URL')]
# [('property', 'http://www.wikidata.org/prop/direct/P443'), ('propertyName', 'pronunciation audio')]
# [('property', 'http://www.wikidata.org/prop/direct/P4457'), ('propertyName', 'DAHR artist ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P460'), ('propertyName', 'said to be the same as')]
# [('property', 'http://www.wikidata.org/prop/direct/P4619'), ('propertyName', 'National Library of Brazil ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P50'), ('propertyName', 'author')]
# [('property', 'http://www.wikidata.org/prop/direct/P5019'), ('propertyName', 'Brockhaus Enzyklopädie online ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P577'), ('propertyName', 'publication date')]
# [('property', 'http://www.wikidata.org/prop/direct/P582'), ('propertyName', 'end time')]
# [('property', 'http://www.wikidata.org/prop/direct/P6269'), ('propertyName', 'API endpoint')]
# [('property', 'http://www.wikidata.org/prop/direct/P6283'), ('propertyName', 'MNopedia ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P648'), ('propertyName', 'Open Library ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7644'), ('propertyName', 'Encyclopedia of Cleveland History ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7666'), ('propertyName', 'Visuotinė lietuvių enciklopedija ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P797'), ('propertyName', 'authority')]
# [('property', 'http://www.wikidata.org/prop/direct/P7982'), ('propertyName', 'Hrvatska enciklopedija ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P8189'), ('propertyName', 'National Library of Israel J9U ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P8349'), ('propertyName', 'Proleksis enciklopedija ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P8672'), ('propertyName', 'Twitter topic ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P8972'), ('propertyName', 'small logo or icon')]
# [('property', 'http://www.wikidata.org/prop/direct/P9138'), ('propertyName', 'service status information URL')]
# [('property', 'http://www.wikidata.org/prop/direct/P9368'), ('propertyName', 'CNA topic ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P953'), ('propertyName', 'full work available at URL')]
# [('property', 'http://www.wikidata.org/prop/direct/P9852'), ('propertyName', 'Media Bias/Fact Check ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P989'), ('propertyName', 'spoken text audio')]
# [('property', 'http://www.wikidata.org/prop/direct/P3875'), ('propertyName', 'Justia Patents company ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6010'), ('propertyName', 'Encyclopedia of Alabama ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7534'), ('propertyName', 'MIC market code')]
# [('property', 'http://www.wikidata.org/prop/direct/P8118'), ('propertyName', 'Forest Stewardship Council Certificate Code')]
# [('property', 'http://www.wikidata.org/prop/direct/P4446'), ('propertyName', 'reward program')]
# [('property', 'http://www.wikidata.org/prop/direct/P8608'), ('propertyName', 'Fatcat ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P9279'), ('propertyName', 'Egapro gender equality index')]
# [('property', 'http://www.wikidata.org/prop/direct/P2133'), ('propertyName', 'total debt')]
# [('property', 'http://www.wikidata.org/prop/direct/P3744'), ('propertyName', 'number of subscribers')]
# [('property', 'http://www.wikidata.org/prop/direct/P3115'), ('propertyName', 'ISzDb company ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1042'), ('propertyName', 'ZDB ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1055'), ('propertyName', 'NLM Unique ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1132'), ('propertyName', 'number of participants')]
# [('property', 'http://www.wikidata.org/prop/direct/P1144'), ('propertyName', 'Library of Congress Control Number (LCCN) (bibliographic)')]
# [('property', 'http://www.wikidata.org/prop/direct/P1151'), ('propertyName', "topic's main Wikimedia portal")]
# [('property', 'http://www.wikidata.org/prop/direct/P1156'), ('propertyName', 'Scopus source ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1220'), ('propertyName', 'Internet Broadway Database person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P123'), ('propertyName', 'publisher')]
# [('property', 'http://www.wikidata.org/prop/direct/P1233'), ('propertyName', 'Internet Speculative Fiction Database author ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1387'), ('propertyName', 'political alignment')]
# [('property', 'http://www.wikidata.org/prop/direct/P1411'), ('propertyName', 'nominated for')]
# [('property', 'http://www.wikidata.org/prop/direct/P1476'), ('propertyName', 'title')]
# [('property', 'http://www.wikidata.org/prop/direct/P1482'), ('propertyName', 'Stack Exchange tag')]
# [('property', 'http://www.wikidata.org/prop/direct/P1616'), ('propertyName', 'SIREN number')]
# [('property', 'http://www.wikidata.org/prop/direct/P1766'), ('propertyName', 'place name sign')]
# [('property', 'http://www.wikidata.org/prop/direct/P2031'), ('propertyName', 'work period (start)')]
# [('property', 'http://www.wikidata.org/prop/direct/P2042'), ('propertyName', 'Artsy artist ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2267'), ('propertyName', 'PolitiFact people and groups ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P236'), ('propertyName', 'ISSN')]
# [('property', 'http://www.wikidata.org/prop/direct/P2390'), ('propertyName', 'Ballotpedia ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P243'), ('propertyName', 'OCLC control number')]
# [('property', 'http://www.wikidata.org/prop/direct/P2813'), ('propertyName', 'house publication')]
# [('property', 'http://www.wikidata.org/prop/direct/P2896'), ('propertyName', 'publication interval')]
# [('property', 'http://www.wikidata.org/prop/direct/P291'), ('propertyName', 'place of publication')]
# [('property', 'http://www.wikidata.org/prop/direct/P2966'), ('propertyName', 'National Library of Wales Authority ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3040'), ('propertyName', 'SoundCloud ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3219'), ('propertyName', 'Encyclopædia Universalis ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3280'), ('propertyName', 'BAnQ author ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3479'), ('propertyName', 'Omni topic ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3509'), ('propertyName', 'Dagens Nyheter topic ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3762'), ('propertyName', 'openMLOL author ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3847'), ('propertyName', 'Open Library subject ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3912'), ('propertyName', 'newspaper format')]
# [('property', 'http://www.wikidata.org/prop/direct/P4725'), ('propertyName', 'C-SPAN organization ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5396'), ('propertyName', 'Online Books Page publication ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5454'), ('propertyName', 'USNPL ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6136'), ('propertyName', 'Newseum newspaper front page ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6157'), ('propertyName', 'Google News publication ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6251'), ('propertyName', 'catchphrase')]
# [('property', 'http://www.wikidata.org/prop/direct/P6363'), ('propertyName', 'WordLift URL')]
# [('property', 'http://www.wikidata.org/prop/direct/P6463'), ('propertyName', "Rock's Backpages publication ID")]
# [('property', 'http://www.wikidata.org/prop/direct/P6619'), ('propertyName', 'XING company ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P674'), ('propertyName', 'characters')]
# [('property', 'http://www.wikidata.org/prop/direct/P6760'), ('propertyName', 'Know Your Meme ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6766'), ('propertyName', "Who's on First ID")]
# [('property', 'http://www.wikidata.org/prop/direct/P6821'), ('propertyName', 'Uppsala University Alvin ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6849'), ('propertyName', 'DR topic ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6981'), ('propertyName', 'ACNP journal ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7012'), ('propertyName', 'World Encyclopedia of Puppetry Arts ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7085'), ('propertyName', 'TikTok username')]
# [('property', 'http://www.wikidata.org/prop/direct/P7212'), ('propertyName', 'LyricsTranslate ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7259'), ('propertyName', 'Newspapers.com paper ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7293'), ('propertyName', 'PLWABN ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7363'), ('propertyName', 'ISSN-L')]
# [('property', 'http://www.wikidata.org/prop/direct/P747'), ('propertyName', 'has edition or translation')]
# [('property', 'http://www.wikidata.org/prop/direct/P8179'), ('propertyName', 'Canadiana NCF ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P822'), ('propertyName', 'mascot')]
# [('property', 'http://www.wikidata.org/prop/direct/P8507'), ('propertyName', 'Legacy.com newspaper ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P8875'), ('propertyName', 'indexed in bibliographic review')]
# [('property', 'http://www.wikidata.org/prop/direct/P9035'), ('propertyName', 'Muck Rack media outlet ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P9100'), ('propertyName', 'GitHub topic')]
# [('property', 'http://www.wikidata.org/prop/direct/P98'), ('propertyName', 'editor')]
# [('property', 'http://www.wikidata.org/prop/direct/P996'), ('propertyName', 'document file on Wikimedia Commons')]
# [('property', 'http://www.wikidata.org/prop/direct/P998'), ('propertyName', 'Curlie ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2984'), ('propertyName', 'Snapchat username')]
# [('property', 'http://www.wikidata.org/prop/direct/P3943'), ('propertyName', 'Tumblr username')]
# [('property', 'http://www.wikidata.org/prop/direct/P3979'), ('propertyName', 'Unifrance company ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4265'), ('propertyName', 'Reddit username')]
# [('property', 'http://www.wikidata.org/prop/direct/P4440'), ('propertyName', 'Biblioteca Nacional de México ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4903'), ('propertyName', 'New Georgia Encyclopedia ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P8359'), ('propertyName', 'Dewey Decimal Classification (works and editions)')]
# [('property', 'http://www.wikidata.org/prop/direct/P8360'), ('propertyName', 'Library of Congress Classification (works and editions)')]
# [('property', 'http://www.wikidata.org/prop/direct/P4482'), ('propertyName', 'INDUCKS publisher ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P114'), ('propertyName', 'airline alliance')]
# [('property', 'http://www.wikidata.org/prop/direct/P230'), ('propertyName', 'ICAO airline designator')]
# [('property', 'http://www.wikidata.org/prop/direct/P5579'), ('propertyName', 'flight-report.com Airline identifier')]
# [('property', 'http://www.wikidata.org/prop/direct/P5703'), ('propertyName', 'airline accounting code')]
# [('property', 'http://www.wikidata.org/prop/direct/P3234'), ('propertyName', 'Code List for Cultural Heritage Organizations')]
# [('property', 'http://www.wikidata.org/prop/direct/P8563'), ('propertyName', 'Emporis company ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6451'), ('propertyName', 'Zhihu username')]
# [('property', 'http://www.wikidata.org/prop/direct/P1739'), ('propertyName', 'CiNii book ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2232'), ('propertyName', 'cash')]
# [('property', 'http://www.wikidata.org/prop/direct/P4742'), ('propertyName', 'Uniform Resource Identifier Scheme')]
# [('property', 'http://www.wikidata.org/prop/direct/P7313'), ('propertyName', 'Rate Your Music label ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5434'), ('propertyName', 'Gfycat user ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1005'), ('propertyName', 'Portuguese National Library ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1245'), ('propertyName', 'OmegaWiki Defined Meaning')]
# [('property', 'http://www.wikidata.org/prop/direct/P136'), ('propertyName', 'genre')]
# [('property', 'http://www.wikidata.org/prop/direct/P1455'), ('propertyName', 'list of works')]
# [('property', 'http://www.wikidata.org/prop/direct/P2184'), ('propertyName', 'history of topic')]
# [('property', 'http://www.wikidata.org/prop/direct/P2283'), ('propertyName', 'uses')]
# [('property', 'http://www.wikidata.org/prop/direct/P2942'), ('propertyName', 'Dailymotion channel ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3267'), ('propertyName', 'Flickr user ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3308'), ('propertyName', 'lib.reviews ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3365'), ('propertyName', 'Treccani ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3782'), ('propertyName', 'Artnet artist ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P437'), ('propertyName', 'distribution format')]
# [('property', 'http://www.wikidata.org/prop/direct/P5009'), ('propertyName', 'complies with')]
# [('property', 'http://www.wikidata.org/prop/direct/P5063'), ('propertyName', 'Interlingual Index ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5084'), ('propertyName', 'Yahoo Answers category')]
# [('property', 'http://www.wikidata.org/prop/direct/P5247'), ('propertyName', 'Giant Bomb ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5357'), ('propertyName', 'The Encyclopedia of Science Fiction ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6573'), ('propertyName', 'Klexikon article ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7140'), ('propertyName', 'München Wiki article ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P750'), ('propertyName', 'distributed by')]
# [('property', 'http://www.wikidata.org/prop/direct/P7771'), ('propertyName', 'PersonalData.IO ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7865'), ('propertyName', 'CoBiS author ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P8814'), ('propertyName', 'WordNet 3.1 Synset ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P898'), ('propertyName', 'IPA transcription')]
# [('property', 'http://www.wikidata.org/prop/direct/P9618'), ('propertyName', 'AlternativeTo software ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P968'), ('propertyName', 'email address')]
# [('property', 'http://www.wikidata.org/prop/direct/P9775'), ('propertyName', "Treccani's Lessico del XXI Secolo ID")]
# [('property', 'http://www.wikidata.org/prop/direct/P2399'), ('propertyName', 'British Council artist ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3579'), ('propertyName', 'Sina Weibo user ID')]
# ...
# [('property', 'http://www.wikidata.org/prop/direct/P8381'), ('propertyName', 'Emmys person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4438'), ('propertyName', 'BFI Films, TV and people ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P737'), ('propertyName', 'influenced by')]
# [('property', 'http://www.wikidata.org/prop/direct/P3549'), ('propertyName', 'Australian Company Number')]
# [('property', 'http://www.wikidata.org/prop/direct/P6550'), ('propertyName', 'Pacific Coast Architecture Database firm ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1995'), ('propertyName', 'health specialty')]
# [('property', 'http://www.wikidata.org/prop/direct/P144'), ('propertyName', 'based on')]
# [('property', 'http://www.wikidata.org/prop/direct/P902'), ('propertyName', 'HDS ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5283'), ('propertyName', 'Strava ID of a professional sport person')]
# [('property', 'http://www.wikidata.org/prop/direct/P4496'), ('propertyName', 'NACE code')]
# [('property', 'http://www.wikidata.org/prop/direct/P2078'), ('propertyName', 'user manual URL')]
# [('property', 'http://www.wikidata.org/prop/direct/P2613'), ('propertyName', 'TED talk ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P8811'), ('propertyName', 'Twitch team ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1325'), ('propertyName', 'external data available at')]
# [('property', 'http://www.wikidata.org/prop/direct/P2910'), ('propertyName', 'icon')]
# [('property', 'http://www.wikidata.org/prop/direct/P6723'), ('propertyName', 'BlackPast.org ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7163'), ('propertyName', 'typically sells')]
# [('property', 'http://www.wikidata.org/prop/direct/P8178'), ('propertyName', 'motorsportstats.com team ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1280'), ('propertyName', 'CONOR.SI ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3435'), ('propertyName', 'VGMdb artist ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3827'), ('propertyName', 'JSTOR topic ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5266'), ('propertyName', 'Finnish national bibliography corporate name ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P8346'), ('propertyName', 'Nomor Pokok Wajib Pajak (organisation or corporation)')]
# [('property', 'http://www.wikidata.org/prop/direct/P172'), ('propertyName', 'ethnic group')]
# [('property', 'http://www.wikidata.org/prop/direct/P4644'), ('propertyName', 'ESCO skill ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P608'), ('propertyName', 'exhibition history')]
# [('property', 'http://www.wikidata.org/prop/direct/P8290'), ('propertyName', 'Archivio Storico Ricordi person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P8799'), ('propertyName', 'Twitch tag ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P21'), ('propertyName', 'sex or gender')]
# [('property', 'http://www.wikidata.org/prop/direct/P2412'), ('propertyName', 'FMD designer ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1281'), ('propertyName', 'WOEID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2001'), ('propertyName', 'Revised Romanization')]
# [('property', 'http://www.wikidata.org/prop/direct/P4746'), ('propertyName', 'Elhuyar ZTH ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6793'), ('propertyName', 'WMI code')]
# [('property', 'http://www.wikidata.org/prop/direct/P8584'), ('propertyName', 'Wikipedia Library partner ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3207'), ('propertyName', 'Vine user ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P709'), ('propertyName', 'Historic Scotland ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3215'), ('propertyName', 'SIRET number')]
# [('property', 'http://www.wikidata.org/prop/direct/P5504'), ('propertyName', 'RISM ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P839'), ('propertyName', 'IMSLP ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1899'), ('propertyName', 'LibriVox author ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7950'), ('propertyName', 'Marvel Comics creators ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7951'), ('propertyName', 'DC Comics talent ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P9319'), ('propertyName', 'Dark Horse creator ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P364'), ('propertyName', 'original language of film or TV show')]
# [('property', 'http://www.wikidata.org/prop/direct/P86'), ('propertyName', 'composer')]
# [('property', 'http://www.wikidata.org/prop/direct/P4107'), ('propertyName', 'Framalibre ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2850'), ('propertyName', 'Apple Music artist ID (American version)')]
# [('property', 'http://www.wikidata.org/prop/direct/P7195'), ('propertyName', 'Bandsintown artist ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6276'), ('propertyName', 'Amazon Music artist ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7837'), ('propertyName', 'Nederlands Fotomuseum photographer ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5052'), ('propertyName', 'supervisory board member')]
# [('property', 'http://www.wikidata.org/prop/direct/P3898'), ('propertyName', 'Hotels.com hotel ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3134'), ('propertyName', 'TripAdvisor ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2851'), ('propertyName', 'payment types accepted')]
# [('property', 'http://www.wikidata.org/prop/direct/P5651'), ('propertyName', 'Expedia hotel ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6720'), ('propertyName', 'interwiki prefix at Wikimedia')]
# [('property', 'http://www.wikidata.org/prop/direct/P1408'), ('propertyName', 'licensed to broadcast to')]
# [('property', 'http://www.wikidata.org/prop/direct/P2603'), ('propertyName', 'Kinopoisk film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3120'), ('propertyName', 'TOID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5909'), ('propertyName', 'HKCAN ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5297'), ('propertyName', 'Companies House officer ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P607'), ('propertyName', 'conflict')]
# [('property', 'http://www.wikidata.org/prop/direct/P6216'), ('propertyName', 'copyright status')]
# [('property', 'http://www.wikidata.org/prop/direct/P7704'), ('propertyName', 'Europeana entity')]
# [('property', 'http://www.wikidata.org/prop/direct/P8649'), ('propertyName', 'National Park Service place ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P8246'), ('propertyName', 'Natural Atlas ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P8868'), ('propertyName', 'AAA hotel ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1640'), ('propertyName', 'curator')]
# [('property', 'http://www.wikidata.org/prop/direct/P179'), ('propertyName', 'part of the series')]
# [('property', 'http://www.wikidata.org/prop/direct/P3965'), ('propertyName', 'Bridgeman artist ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P61'), ('propertyName', 'discoverer or inventor')]
# [('property', 'http://www.wikidata.org/prop/direct/P6162'), ('propertyName', 'Luding game publisher ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P108'), ('propertyName', 'employer')]
# [('property', 'http://www.wikidata.org/prop/direct/P5936'), ('propertyName', 'old-computers.com ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5586'), ('propertyName', 'Times Higher Education World University ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1893'), ('propertyName', 'OpenPlaques plaque ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2651'), ('propertyName', 'CRICOS Provider Code')]
# [('property', 'http://www.wikidata.org/prop/direct/P8182'), ('propertyName', 'South African Company Registration Number')]
# [('property', 'http://www.wikidata.org/prop/direct/P8351'), ('propertyName', 'vglist video game ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3183'), ('propertyName', 'Wall Street Journal topic ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1163'), ('propertyName', 'media type')]
# [('property', 'http://www.wikidata.org/prop/direct/P2360'), ('propertyName', 'intended public')]
# [('property', 'http://www.wikidata.org/prop/direct/P2052'), ('propertyName', 'speed')]
# [('property', 'http://www.wikidata.org/prop/direct/P4096'), ('propertyName', 'RePEc institute ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3872'), ('propertyName', 'patronage')]
# [('property', 'http://www.wikidata.org/prop/direct/P1292'), ('propertyName', 'DNB editions')]
# [('property', 'http://www.wikidata.org/prop/direct/P1753'), ('propertyName', 'list related to category')]
# [('property', 'http://www.wikidata.org/prop/direct/P1138'), ('propertyName', 'Kunstindeks Danmark Artist ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7467'), ('propertyName', 'Broadway Photographs person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6949'), ('propertyName', 'announcement date')]
# [('property', 'http://www.wikidata.org/prop/direct/P8324'), ('propertyName', 'funder')]
# [('property', 'http://www.wikidata.org/prop/direct/P1891'), ('propertyName', 'signatory')]
# [('property', 'http://www.wikidata.org/prop/direct/P186'), ('propertyName', 'made from material')]
# [('property', 'http://www.wikidata.org/prop/direct/P7618'), ('propertyName', 'Virginia Landmarks Register ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2872'), ('propertyName', 'visitor centre')]
# [('property', 'http://www.wikidata.org/prop/direct/P2308'), ('propertyName', 'class')]
# [('property', 'http://www.wikidata.org/prop/direct/P5749'), ('propertyName', 'Amazon Standard Identification Number')]
# [('property', 'http://www.wikidata.org/prop/direct/P2209'), ('propertyName', 'SourceForge project')]
# [('property', 'http://www.wikidata.org/prop/direct/P7591'), ('propertyName', 'VideoGameGeek game ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5308'), ('propertyName', 'Dictionary of Scottish Architects ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6804'), ('propertyName', 'Art Gallery of South Australia creator ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P8210'), ('propertyName', 'LombardiaBeniCulturali artwork author ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P734'), ('propertyName', 'family name')]
# [('property', 'http://www.wikidata.org/prop/direct/P742'), ('propertyName', 'pseudonym')]
# [('property', 'http://www.wikidata.org/prop/direct/P2904'), ('propertyName', 'Beer Advocate brewery ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2595'), ('propertyName', 'maximum gradient')]
# [('property', 'http://www.wikidata.org/prop/direct/P2342'), ('propertyName', 'AGORHA person/institution ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P9101'), ('propertyName', 'Discord username')]
# [('property', 'http://www.wikidata.org/prop/direct/P1960'), ('propertyName', 'Google Scholar author ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6634'), ('propertyName', 'LinkedIn personal profile ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P8827'), ('propertyName', 'GitLab username')]
# [('property', 'http://www.wikidata.org/prop/direct/P8815'), ('propertyName', 'IAFD film distributor ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3125'), ('propertyName', 'EDRPOU code')]
# [('property', 'http://www.wikidata.org/prop/direct/P8256'), ('propertyName', 'Super Mario Wiki ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4845'), ('propertyName', 'Bulbapedia article')]
# [('property', 'http://www.wikidata.org/prop/direct/P6552'), ('propertyName', 'Twitter user numeric ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P8559'), ('propertyName', 'Chrome Webstore extension ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P931'), ('propertyName', 'place served by transport hub')]
# [('property', 'http://www.wikidata.org/prop/direct/P516'), ('propertyName', 'powered by')]
# [('property', 'http://www.wikidata.org/prop/direct/P4173'), ('propertyName', 'Instagram location ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1399'), ('propertyName', 'convicted of')]
# [('property', 'http://www.wikidata.org/prop/direct/P2025'), ('propertyName', 'Find A Grave cemetery ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4970'), ('propertyName', 'alternate names')]
# [('property', 'http://www.wikidata.org/prop/direct/P3989'), ('propertyName', 'members have occupation')]
# [('property', 'http://www.wikidata.org/prop/direct/P1412'), ('propertyName', 'languages spoken, written or signed')]
# [('property', 'http://www.wikidata.org/prop/direct/P7711'), ('propertyName', 'Joconde author ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2067'), ('propertyName', 'mass')]
# [('property', 'http://www.wikidata.org/prop/direct/P264'), ('propertyName', 'record label')]
# [('property', 'http://www.wikidata.org/prop/direct/P9509'), ('propertyName', 'Mixcloud ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P8657'), ('propertyName', 'photoLondon ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4300'), ('propertyName', 'YouTube playlist ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5271'), ('propertyName', 'Saint Louis Art Museum person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1659'), ('propertyName', 'see also')]
# [('property', 'http://www.wikidata.org/prop/direct/P206'), ('propertyName', 'located in or next to body of water')]
# [('property', 'http://www.wikidata.org/prop/direct/P3087'), ('propertyName', 'fiscal/tax revenue')]
# [('property', 'http://www.wikidata.org/prop/direct/P3086'), ('propertyName', 'speed limit')]
# [('property', 'http://www.wikidata.org/prop/direct/P92'), ('propertyName', 'main regulatory text')]
# [('property', 'http://www.wikidata.org/prop/direct/P1059'), ('propertyName', 'CVR number')]
# [('property', 'http://www.wikidata.org/prop/direct/P2079'), ('propertyName', 'fabrication method')]
# [('property', 'http://www.wikidata.org/prop/direct/P1595'), ('propertyName', 'charge')]
# [('property', 'http://www.wikidata.org/prop/direct/P5456'), ('propertyName', 'TasteAtlas ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1942'), ('propertyName', 'McCune-Reischauer romanization')]
# [('property', 'http://www.wikidata.org/prop/direct/P5034'), ('propertyName', 'National Library of Korea ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7429'), ('propertyName', 'Bundle ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P739'), ('propertyName', 'ammunition')]
# [('property', 'http://www.wikidata.org/prop/direct/P2175'), ('propertyName', 'medical condition treated')]
# [('property', 'http://www.wikidata.org/prop/direct/P1065'), ('propertyName', 'archive URL')]
# [('property', 'http://www.wikidata.org/prop/direct/P3026'), ('propertyName', 'closed on')]
# [('property', 'http://www.wikidata.org/prop/direct/P4156'), ('propertyName', 'Czech Registration ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P8987'), ('propertyName', 'ISDS ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5930'), ('propertyName', 'Open Food Facts ingredient ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4738'), ('propertyName', 'Yale Center for British Art artwork ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2432'), ('propertyName', 'J. Paul Getty Museum artist id')]
# [('property', 'http://www.wikidata.org/prop/direct/P2918'), ('propertyName', 'PO Box')]
# [('property', 'http://www.wikidata.org/prop/direct/P3372'), ('propertyName', 'Auckland Art Gallery artist ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7324'), ('propertyName', 'iHeartRadio podcast ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4818'), ('propertyName', 'Panoptikum podcast ID')]
# 1066

# %%
#let's try and filter the properties by name, we're looking for keywords such as number of employees, revenue, capital, assets
#sector, if a company owns or is onwned by some other company, the ceo...
q = f"""
select distinct ?property ?propertyName where{{
# ?b wdt:P31 wd:Q4830453 .
# ?b ?property ?predicate .
# ?b wdt:P17 ?country .
filter(?country in (wd:Q16, wd:Q145, wd:Q30)) .
# ?property <http://schema.org/name> ?propertyName .
filter regex(?propertyName, '.*(employee|revenue|capital|asset|owne|ceo|c.e.o.|sector).*' ,'i') .
}}
"""
run_query(q)
# Out:
# [('property', 'http://www.wikidata.org/prop/direct/P1128'), ('propertyName', 'employees')]
# [('property', 'http://www.wikidata.org/prop/direct/P127'), ('propertyName', 'owned by')]
# [('property', 'http://www.wikidata.org/prop/direct/P1830'), ('propertyName', 'owner of')]
# [('property', 'http://www.wikidata.org/prop/direct/P2139'), ('propertyName', 'total revenue')]
# [('property', 'http://www.wikidata.org/prop/direct/P2403'), ('propertyName', 'total assets')]
# [('property', 'http://www.wikidata.org/prop/direct/P2226'), ('propertyName', 'market capitalization')]
# [('property', 'http://www.wikidata.org/prop/direct/P4103'), ('propertyName', 'assets under management')]
# [('property', 'http://www.wikidata.org/prop/direct/P2663'), ('propertyName', 'common equity tier 1 capital ratio (CETI)')]
# [('property', 'http://www.wikidata.org/prop/direct/P4195'), ('propertyName', 'category for employees of the organization')]
# [('property', 'http://www.wikidata.org/prop/direct/P3087'), ('propertyName', 'fiscal/tax revenue')]
# 10

# %%
#let's define for now variables for the properties we care about
owned_by = 'wdt:P127'
owner_of = 'wdt:P1830'
n_employees = 'wdt:P1128'
total_revenue = 'wdt:P2139'
total_assets = 'wdt:P2403'
#we couldn't find a property related to sector, let's try with a company we know, for example Microsoft, and see its properties
q = f"""
select distinct ?companyName ?property ?propertyName where{{
# ?company wdt:P31 wd:Q4830453 ;
    <http://schema.org/name> ?companyName ;
    wdt:P17 wd:Q30 ;
    # ?property ?o .
# ?property <http://schema.org/name> ?propertyName .
filter regex(?companyName, 'microsoft', 'i')
}}
"""
run_query(q)
# Out:
# [('companyName', 'Microsoft'), ('property', 'http://www.wikidata.org/prop/direct/P8060'), ('propertyName', 'Glassdoor company ID')]
# [('companyName', 'Microsoft'), ('property', 'http://www.wikidata.org/prop/direct/P8939'), ('propertyName', 'Google Play developer slug')]
# [('companyName', 'Microsoft'), ('property', 'http://www.wikidata.org/prop/direct/P1005'), ('propertyName', 'Portuguese National Library ID')]
# [('companyName', 'Microsoft'), ('property', 'http://www.wikidata.org/prop/direct/P1037'), ('propertyName', 'director / manager')]
# [('companyName', 'Microsoft'), ('property', 'http://www.wikidata.org/prop/direct/P1056'), ('propertyName', 'product or material produced')]
# [('companyName', 'Microsoft'), ('property', 'http://www.wikidata.org/prop/direct/P112'), ('propertyName', 'founded by')]
# [('companyName', 'Microsoft'), ('property', 'http://www.wikidata.org/prop/direct/P1128'), ('propertyName', 'employees')]
# [('companyName', 'Microsoft'), ('property', 'http://www.wikidata.org/prop/direct/P1151'), ('propertyName', "topic's main Wikimedia portal")]
# [('companyName', 'Microsoft'), ('property', 'http://www.wikidata.org/prop/direct/P1167'), ('propertyName', 'USB vendor ID')]
# [('companyName', 'Microsoft'), ('property', 'http://www.wikidata.org/prop/direct/P1207'), ('propertyName', 'NUKAT ID')]
# [('companyName', 'Microsoft'), ('property', 'http://www.wikidata.org/prop/direct/P1245'), ('propertyName', 'OmegaWiki Defined Meaning')]
# [('companyName', 'Microsoft'), ('property', 'http://www.wikidata.org/prop/direct/P127'), ('propertyName', 'owned by')]
# [('companyName', 'Microsoft'), ('property', 'http://www.wikidata.org/prop/direct/P1273'), ('propertyName', 'CANTIC ID')]
# [('companyName', 'Microsoft'), ('property', 'http://www.wikidata.org/prop/direct/P1278'), ('propertyName', 'Legal Entity Identifier')]
# [('companyName', 'Microsoft'), ('property', 'http://www.wikidata.org/prop/direct/P1296'), ('propertyName', 'Gran Enciclopèdia Catalana ID')]
# [('companyName', 'Microsoft'), ('property', 'http://www.wikidata.org/prop/direct/P1315'), ('propertyName', 'NLA Trove ID')]
# [('companyName', 'Microsoft'), ('property', 'http://www.wikidata.org/prop/direct/P1320'), ('propertyName', 'OpenCorporates ID')]
# [('companyName', 'Microsoft'), ('property', 'http://www.wikidata.org/prop/direct/P1343'), ('propertyName', 'described by source')]
# [('companyName', 'Microsoft'), ('property', 'http://www.wikidata.org/prop/direct/P1417'), ('propertyName', 'Encyclopædia Britannica Online ID')]
# [('companyName', 'Microsoft'), ('property', 'http://www.wikidata.org/prop/direct/P1448'), ('propertyName', 'official name')]
# [('companyName', 'Microsoft'), ('property', 'http://www.wikidata.org/prop/direct/P1454'), ('propertyName', 'legal form')]
# [('companyName', 'Microsoft'), ('property', 'http://www.wikidata.org/prop/direct/P154'), ('propertyName', 'logo image')]
# [('companyName', 'Microsoft'), ('property', 'http://www.wikidata.org/prop/direct/P1581'), ('propertyName', 'official blog')]
# [('companyName', 'Microsoft'), ('property', 'http://www.wikidata.org/prop/direct/P159'), ('propertyName', 'headquarters location')]
# [('companyName', 'Microsoft'), ('property', 'http://www.wikidata.org/prop/direct/P166'), ('propertyName', 'award received')]
# [('companyName', 'Microsoft'), ('property', 'http://www.wikidata.org/prop/direct/P169'), ('propertyName', 'chief executive officer')]
# [('companyName', 'Microsoft'), ('property', 'http://www.wikidata.org/prop/direct/P17'), ('propertyName', 'country')]
# [('companyName', 'Microsoft'), ('property', 'http://www.wikidata.org/prop/direct/P18'), ('propertyName', 'image')]
# [('companyName', 'Microsoft'), ('property', 'http://www.wikidata.org/prop/direct/P1830'), ('propertyName', 'owner of')]
# [('companyName', 'Microsoft'), ('property', 'http://www.wikidata.org/prop/direct/P199'), ('propertyName', 'business division')]
# [('companyName', 'Microsoft'), ('property', 'http://www.wikidata.org/prop/direct/P2002'), ('propertyName', 'Twitter username')]
# [('companyName', 'Microsoft'), ('property', 'http://www.wikidata.org/prop/direct/P2003'), ('propertyName', 'Instagram username')]
# [('companyName', 'Microsoft'), ('property', 'http://www.wikidata.org/prop/direct/P2011'), ('propertyName', 'Cooper-Hewitt Person ID')]
# [('companyName', 'Microsoft'), ('property', 'http://www.wikidata.org/prop/direct/P2013'), ('propertyName', 'Facebook ID')]
# [('companyName', 'Microsoft'), ('property', 'http://www.wikidata.org/prop/direct/P2037'), ('propertyName', 'GitHub username')]
# [('companyName', 'Microsoft'), ('property', 'http://www.wikidata.org/prop/direct/P2088'), ('propertyName', 'Crunchbase organization ID')]
# [('companyName', 'Microsoft'), ('property', 'http://www.wikidata.org/prop/direct/P213'), ('propertyName', 'ISNI')]
# [('companyName', 'Microsoft'), ('property', 'http://www.wikidata.org/prop/direct/P2139'), ('propertyName', 'total revenue')]
# [('companyName', 'Microsoft'), ('property', 'http://www.wikidata.org/prop/direct/P214'), ('propertyName', 'VIAF ID')]
# [('companyName', 'Microsoft'), ('property', 'http://www.wikidata.org/prop/direct/P2184'), ('propertyName', 'history of topic')]
# [('companyName', 'Microsoft'), ('property', 'http://www.wikidata.org/prop/direct/P2226'), ('propertyName', 'market capitalization')]
# [('companyName', 'Microsoft'), ('property', 'http://www.wikidata.org/prop/direct/P227'), ('propertyName', 'GND ID')]
# [('companyName', 'Microsoft'), ('property', 'http://www.wikidata.org/prop/direct/P2295'), ('propertyName', 'net profit')]
# [('companyName', 'Microsoft'), ('property', 'http://www.wikidata.org/prop/direct/P2397'), ('propertyName', 'YouTube channel ID')]
# [('companyName', 'Microsoft'), ('property', 'http://www.wikidata.org/prop/direct/P2403'), ('propertyName', 'total assets')]
# [('companyName', 'Microsoft'), ('property', 'http://www.wikidata.org/prop/direct/P2427'), ('propertyName', 'GRID ID')]
# [('companyName', 'Microsoft'), ('property', 'http://www.wikidata.org/prop/direct/P244'), ('propertyName', 'Library of Congress authority ID')]
# [('companyName', 'Microsoft'), ('property', 'http://www.wikidata.org/prop/direct/P245'), ('propertyName', 'Union List of Artist Names ID')]
# [('companyName', 'Microsoft'), ('property', 'http://www.wikidata.org/prop/direct/P2581'), ('propertyName', 'BabelNet ID')]
# [('companyName', 'Microsoft'), ('property', 'http://www.wikidata.org/prop/direct/P2612'), ('propertyName', 'TED topic ID')]
# [('companyName', 'Microsoft'), ('property', 'http://www.wikidata.org/prop/direct/P2627'), ('propertyName', 'ISO 9362 SWIFT/BIC code')]
# [('companyName', 'Microsoft'), ('property', 'http://www.wikidata.org/prop/direct/P2657'), ('propertyName', 'EU Transparency Register ID')]
# [('companyName', 'Microsoft'), ('property', 'http://www.wikidata.org/prop/direct/P268'), ('propertyName', 'Bibliothèque nationale de France ID')]
# [('companyName', 'Microsoft'), ('property', 'http://www.wikidata.org/prop/direct/P269'), ('propertyName', 'IdRef ID')]
# [('companyName', 'Microsoft'), ('property', 'http://www.wikidata.org/prop/direct/P2924'), ('propertyName', 'Great Russian Encyclopedia Online ID')]
# [('companyName', 'Microsoft'), ('property', 'http://www.wikidata.org/prop/direct/P2959'), ('propertyName', 'permanent duplicated item')]
# [('companyName', 'Microsoft'), ('property', 'http://www.wikidata.org/prop/direct/P31'), ('propertyName', 'instance of')]
# [('companyName', 'Microsoft'), ('property', 'http://www.wikidata.org/prop/direct/P3153'), ('propertyName', 'Crossref funder ID')]
# [('companyName', 'Microsoft'), ('property', 'http://www.wikidata.org/prop/direct/P3221'), ('propertyName', 'New York Times topic ID')]
# [('companyName', 'Microsoft'), ('property', 'http://www.wikidata.org/prop/direct/P3222'), ('propertyName', 'NE.se ID')]
# [('companyName', 'Microsoft'), ('property', 'http://www.wikidata.org/prop/direct/P3225'), ('propertyName', 'Corporate Number (Japan)')]
# [('companyName', 'Microsoft'), ('property', 'http://www.wikidata.org/prop/direct/P3320'), ('propertyName', 'board member')]
# [('companyName', 'Microsoft'), ('property', 'http://www.wikidata.org/prop/direct/P3347'), ('propertyName', 'PermID')]
# [('companyName', 'Microsoft'), ('property', 'http://www.wikidata.org/prop/direct/P3362'), ('propertyName', 'operating income')]
# [('companyName', 'Microsoft'), ('property', 'http://www.wikidata.org/prop/direct/P3365'), ('propertyName', 'Treccani ID')]
# [('companyName', 'Microsoft'), ('property', 'http://www.wikidata.org/prop/direct/P3417'), ('propertyName', 'Quora topic ID')]
# [('companyName', 'Microsoft'), ('property', 'http://www.wikidata.org/prop/direct/P349'), ('propertyName', 'National Diet Library ID')]
# [('companyName', 'Microsoft'), ('property', 'http://www.wikidata.org/prop/direct/P3500'), ('propertyName', 'Ringgold ID')]
# [('companyName', 'Microsoft'), ('property', 'http://www.wikidata.org/prop/direct/P3509'), ('propertyName', 'Dagens Nyheter topic ID')]
# [('companyName', 'Microsoft'), ('property', 'http://www.wikidata.org/prop/direct/P355'), ('propertyName', 'subsidiary')]
# [('companyName', 'Microsoft'), ('property', 'http://www.wikidata.org/prop/direct/P361'), ('propertyName', 'part of')]
# [('companyName', 'Microsoft'), ('property', 'http://www.wikidata.org/prop/direct/P3630'), ('propertyName', 'Babelio author ID')]
# [('companyName', 'Microsoft'), ('property', 'http://www.wikidata.org/prop/direct/P3721'), ('propertyName', 'public key fingerprint')]
# [('companyName', 'Microsoft'), ('property', 'http://www.wikidata.org/prop/direct/P373'), ('propertyName', 'Commons category')]
# [('companyName', 'Microsoft'), ('property', 'http://www.wikidata.org/prop/direct/P3743'), ('propertyName', 'ITU/ISO/IEC object identifier')]
# [('companyName', 'Microsoft'), ('property', 'http://www.wikidata.org/prop/direct/P3761'), ('propertyName', 'IPv4 routing prefix')]
# [('companyName', 'Microsoft'), ('property', 'http://www.wikidata.org/prop/direct/P3762'), ('propertyName', 'openMLOL author ID')]
# [('companyName', 'Microsoft'), ('property', 'http://www.wikidata.org/prop/direct/P3797'), ('propertyName', 'autonomous system number')]
# [('companyName', 'Microsoft'), ('property', 'http://www.wikidata.org/prop/direct/P3836'), ('propertyName', 'Pinterest username')]
# [('companyName', 'Microsoft'), ('property', 'http://www.wikidata.org/prop/direct/P3984'), ('propertyName', 'subreddit')]
# [('companyName', 'Microsoft'), ('property', 'http://www.wikidata.org/prop/direct/P3987'), ('propertyName', 'SHARE Catalogue author ID')]
# [('companyName', 'Microsoft'), ('property', 'http://www.wikidata.org/prop/direct/P4073'), ('propertyName', 'Fandom wiki ID')]
# [('companyName', 'Microsoft'), ('property', 'http://www.wikidata.org/prop/direct/P409'), ('propertyName', 'Libraries Australia ID')]
# [('companyName', 'Microsoft'), ('property', 'http://www.wikidata.org/prop/direct/P414'), ('propertyName', 'stock exchange')]
# [('companyName', 'Microsoft'), ('property', 'http://www.wikidata.org/prop/direct/P4204'), ('propertyName', 'The Times of India topic ID')]
# [('companyName', 'Microsoft'), ('property', 'http://www.wikidata.org/prop/direct/P4264'), ('propertyName', 'LinkedIn company ID')]
# [('companyName', 'Microsoft'), ('property', 'http://www.wikidata.org/prop/direct/P4293'), ('propertyName', 'PM20 folder ID')]
# [('companyName', 'Microsoft'), ('property', 'http://www.wikidata.org/prop/direct/P4342'), ('propertyName', 'Store norske leksikon ID')]
# [('companyName', 'Microsoft'), ('property', 'http://www.wikidata.org/prop/direct/P4354'), ('propertyName', 'search formatter URL')]
# [('companyName', 'Microsoft'), ('property', 'http://www.wikidata.org/prop/direct/P4486'), ('propertyName', 'Google Play developer ID')]
# [('companyName', 'Microsoft'), ('property', 'http://www.wikidata.org/prop/direct/P452'), ('propertyName', 'industry')]
# [('companyName', 'Microsoft'), ('property', 'http://www.wikidata.org/prop/direct/P4527'), ('propertyName', 'UK Parliament thesaurus ID')]
# [('companyName', 'Microsoft'), ('property', 'http://www.wikidata.org/prop/direct/P4613'), ('propertyName', 'Encyclopedia of Modern Ukraine ID')]
# [('companyName', 'Microsoft'), ('property', 'http://www.wikidata.org/prop/direct/P463'), ('propertyName', 'member of')]
# [('companyName', 'Microsoft'), ('property', 'http://www.wikidata.org/prop/direct/P4773'), ('propertyName', 'MobyGames company ID')]
# [('companyName', 'Microsoft'), ('property', 'http://www.wikidata.org/prop/direct/P4776'), ('propertyName', 'MAC Address Block Large ID')]
# [('companyName', 'Microsoft'), ('property', 'http://www.wikidata.org/prop/direct/P488'), ('propertyName', 'chairperson')]
# [('companyName', 'Microsoft'), ('property', 'http://www.wikidata.org/prop/direct/P5260'), ('propertyName', 'App Store developer ID')]
# [('companyName', 'Microsoft'), ('property', 'http://www.wikidata.org/prop/direct/P571'), ('propertyName', 'inception')]
# [('companyName', 'Microsoft'), ('property', 'http://www.wikidata.org/prop/direct/P6262'), ('propertyName', 'Fandom article ID')]
# [('companyName', 'Microsoft'), ('property', 'http://www.wikidata.org/prop/direct/P6366'), ('propertyName', 'Microsoft Academic ID')]
# [('companyName', 'Microsoft'), ('property', 'http://www.wikidata.org/prop/direct/P646'), ('propertyName', 'Freebase ID')]
# [('companyName', 'Microsoft'), ('property', 'http://www.wikidata.org/prop/direct/P6517'), ('propertyName', 'WhoSampled artist ID')]
# [('companyName', 'Microsoft'), ('property', 'http://www.wikidata.org/prop/direct/P6573'), ('propertyName', 'Klexikon article ID')]
# [('companyName', 'Microsoft'), ('property', 'http://www.wikidata.org/prop/direct/P6706'), ('propertyName', 'De Agostini ID')]
# [('companyName', 'Microsoft'), ('property', 'http://www.wikidata.org/prop/direct/P6782'), ('propertyName', 'ROR ID')]
# [('companyName', 'Microsoft'), ('property', 'http://www.wikidata.org/prop/direct/P6849'), ('propertyName', 'DR topic ID')]
# [('companyName', 'Microsoft'), ('property', 'http://www.wikidata.org/prop/direct/P691'), ('propertyName', 'NKCR AUT ID')]
# [('companyName', 'Microsoft'), ('property', 'http://www.wikidata.org/prop/direct/P7014'), ('propertyName', 'terms of service URL')]
# [('companyName', 'Microsoft'), ('property', 'http://www.wikidata.org/prop/direct/P7193'), ('propertyName', 'YesAsia author ID')]
# [('companyName', 'Microsoft'), ('property', 'http://www.wikidata.org/prop/direct/P740'), ('propertyName', 'location of formation')]
# [('companyName', 'Microsoft'), ('property', 'http://www.wikidata.org/prop/direct/P7818'), ('propertyName', 'French Vikidia ID')]
# [('companyName', 'Microsoft'), ('property', 'http://www.wikidata.org/prop/direct/P7827'), ('propertyName', 'Spanish Vikidia ID')]
# [('companyName', 'Microsoft'), ('property', 'http://www.wikidata.org/prop/direct/P7829'), ('propertyName', 'English Vikidia ID')]
# [('companyName', 'Microsoft'), ('property', 'http://www.wikidata.org/prop/direct/P7859'), ('propertyName', 'WorldCat Identities ID')]
# [('companyName', 'Microsoft'), ('property', 'http://www.wikidata.org/prop/direct/P7886'), ('propertyName', 'Media Arts Database ID')]
# [('companyName', 'Microsoft'), ('property', 'http://www.wikidata.org/prop/direct/P7982'), ('propertyName', 'Hrvatska enciklopedija ID')]
# [('companyName', 'Microsoft'), ('property', 'http://www.wikidata.org/prop/direct/P856'), ('propertyName', 'official website')]
# [('companyName', 'Microsoft'), ('property', 'http://www.wikidata.org/prop/direct/P8571'), ('propertyName', 'external auditor')]
# [('companyName', 'Microsoft'), ('property', 'http://www.wikidata.org/prop/direct/P8672'), ('propertyName', 'Twitter topic ID')]
# [('companyName', 'Microsoft'), ('property', 'http://www.wikidata.org/prop/direct/P8687'), ('propertyName', 'social media followers')]
# [('companyName', 'Microsoft'), ('property', 'http://www.wikidata.org/prop/direct/P8885'), ('propertyName', 'Namuwiki ID')]
# [('companyName', 'Microsoft'), ('property', 'http://www.wikidata.org/prop/direct/P8972'), ('propertyName', 'small logo or icon')]
# [('companyName', 'Microsoft'), ('property', 'http://www.wikidata.org/prop/direct/P906'), ('propertyName', 'SELIBR ID')]
# [('companyName', 'Microsoft'), ('property', 'http://www.wikidata.org/prop/direct/P910'), ('propertyName', "topic's main category")]
# [('companyName', 'Microsoft'), ('property', 'http://www.wikidata.org/prop/direct/P935'), ('propertyName', 'Commons gallery')]
# [('companyName', 'Microsoft'), ('property', 'http://www.wikidata.org/prop/direct/P9402'), ('propertyName', 'GameSpot developer ID')]
# [('companyName', 'Microsoft'), ('property', 'http://www.wikidata.org/prop/direct/P946'), ('propertyName', 'ISIN')]
# [('companyName', 'Microsoft'), ('property', 'http://www.wikidata.org/prop/direct/P949'), ('propertyName', 'National Library of Israel ID')]
# [('companyName', 'Microsoft'), ('property', 'http://www.wikidata.org/prop/direct/P950'), ('propertyName', 'Biblioteca Nacional de España ID')]
# [('companyName', 'Microsoft'), ('property', 'http://www.wikidata.org/prop/direct/P9650'), ('propertyName', 'Internet Game Database company ID')]
# [('companyName', 'Microsoft'), ('property', 'http://www.wikidata.org/prop/direct/P973'), ('propertyName', 'described at URL')]
# [('companyName', 'Microsoft'), ('property', 'http://www.wikidata.org/prop/direct/P3242'), ('propertyName', 'SIC code')]
# [('companyName', 'Microsoft'), ('property', 'http://www.wikidata.org/prop/direct/P5531'), ('propertyName', 'Central Index Key')]
# [('companyName', 'Microsoft'), ('property', 'http://www.wikidata.org/prop/direct/P7101'), ('propertyName', 'privacy policy URL')]
# [('companyName', 'Microsoft'), ('property', 'http://www.wikidata.org/prop/direct/P2137'), ('propertyName', 'total equity')]
# [('companyName', 'Microsoft'), ('property', 'http://www.wikidata.org/prop/direct/P3579'), ('propertyName', 'Sina Weibo user ID')]
# [('companyName', 'Microsoft'), ('property', 'http://www.wikidata.org/prop/direct/P4167'), ('propertyName', 'Dagens Næringsliv topic ID')]
# [('companyName', 'Microsoft'), ('property', 'http://www.wikidata.org/prop/direct/P6337'), ('propertyName', 'PCGamingWiki ID')]
# [('companyName', 'Microsoft'), ('property', 'http://www.wikidata.org/prop/direct/P1297'), ('propertyName', 'IRS Employer Identification Number')]
# [('companyName', 'Microsoft'), ('property', 'http://www.wikidata.org/prop/direct/P3875'), ('propertyName', 'Justia Patents company ID')]
# [('companyName', 'Microsoft'), ('property', 'http://www.wikidata.org/prop/direct/P2740'), ('propertyName', 'ResearchGate institute ID')]
# [('companyName', 'Microsoft'), ('property', 'http://www.wikidata.org/prop/direct/P2652'), ('propertyName', 'partnership with')]
# [('companyName', 'Microsoft Online'), ('property', 'http://www.wikidata.org/prop/direct/P1320'), ('propertyName', 'OpenCorporates ID')]
# [('companyName', 'Microsoft Online'), ('property', 'http://www.wikidata.org/prop/direct/P159'), ('propertyName', 'headquarters location')]
# [('companyName', 'Microsoft Online'), ('property', 'http://www.wikidata.org/prop/direct/P17'), ('propertyName', 'country')]
# [('companyName', 'Microsoft Online'), ('property', 'http://www.wikidata.org/prop/direct/P31'), ('propertyName', 'instance of')]
# [('companyName', 'Microsoft Online'), ('property', 'http://www.wikidata.org/prop/direct/P571'), ('propertyName', 'inception')]
# [('companyName', 'Microsoft Online'), ('property', 'http://www.wikidata.org/prop/direct/P749'), ('propertyName', 'parent organization')]
# 149

# %%
#with a more readable output, we're able to find out the properties related to the CEO and the "product or material produced"
ceo = 'wdt:P169'
produces = 'wdt:P1056'
#i forgot to show the company uri, i have to filter by name of the company again
#let's find out the ceo and the product of microsoft
q = f"""
select ?company, ?companyName, ?ceoName, ?product, ?productName where{{
# ?company wdt:P31 wd:Q4830453 ;
    wdt:P17 wd:Q30 ;
    wdt:P169 ?ceo ;
    wdt:P1056 ?product ;
    <http://schema.org/name> ?companyName .
# ?ceo <http://schema.org/name> ?ceoName .
# ?product <http://schema.org/name> ?productName .
filter regex(?companyName, 'microsoft', 'i')
}}
"""
run_query(q)
# Out:
# [('company', 'http://www.wikidata.org/entity/Q2283'), ('companyName', 'Microsoft'), ('ceoName', 'Satya Nadella'), ('product', 'http://www.wikidata.org/entity/Q132020'), ('productName', 'Xbox')]
# [('company', 'http://www.wikidata.org/entity/Q2283'), ('companyName', 'Microsoft'), ('ceoName', 'Satya Nadella'), ('product', 'http://www.wikidata.org/entity/Q1071340'), ('productName', 'Microsoft Servers')]
# [('company', 'http://www.wikidata.org/entity/Q2283'), ('companyName', 'Microsoft'), ('ceoName', 'Satya Nadella'), ('product', 'http://www.wikidata.org/entity/Q134067'), ('productName', 'Microsoft Visual Studio')]
# [('company', 'http://www.wikidata.org/entity/Q2283'), ('companyName', 'Microsoft'), ('ceoName', 'Satya Nadella'), ('product', 'http://www.wikidata.org/entity/Q40984'), ('productName', 'Skype')]
# [('company', 'http://www.wikidata.org/entity/Q2283'), ('companyName', 'Microsoft'), ('ceoName', 'Satya Nadella'), ('product', 'http://www.wikidata.org/entity/Q182496'), ('productName', 'Microsoft Bing')]
# [('company', 'http://www.wikidata.org/entity/Q2283'), ('companyName', 'Microsoft'), ('ceoName', 'Satya Nadella'), ('product', 'http://www.wikidata.org/entity/Q856705'), ('productName', 'Microsoft Dynamics')]
# [('company', 'http://www.wikidata.org/entity/Q2283'), ('companyName', 'Microsoft'), ('ceoName', 'Satya Nadella'), ('product', 'http://www.wikidata.org/entity/Q3966'), ('productName', 'computer hardware')]
# [('company', 'http://www.wikidata.org/entity/Q2283'), ('companyName', 'Microsoft'), ('ceoName', 'Satya Nadella'), ('product', 'http://www.wikidata.org/entity/Q471806'), ('productName', 'Microsoft Surface')]
# [('company', 'http://www.wikidata.org/entity/Q2283'), ('companyName', 'Microsoft'), ('ceoName', 'Satya Nadella'), ('product', 'http://www.wikidata.org/entity/Q11255'), ('productName', 'Microsoft Office')]
# [('company', 'http://www.wikidata.org/entity/Q2283'), ('companyName', 'Microsoft'), ('ceoName', 'Satya Nadella'), ('product', 'http://www.wikidata.org/entity/Q16538568'), ('productName', 'Microsoft Mobile')]
# [('company', 'http://www.wikidata.org/entity/Q2283'), ('companyName', 'Microsoft'), ('ceoName', 'Satya Nadella'), ('product', 'http://www.wikidata.org/entity/Q15281614'), ('productName', 'Xbox')]
# [('company', 'http://www.wikidata.org/entity/Q2283'), ('companyName', 'Microsoft'), ('ceoName', 'Satya Nadella'), ('product', 'http://www.wikidata.org/entity/Q1851989'), ('productName', 'list of Microsoft software applications')]
# [('company', 'http://www.wikidata.org/entity/Q2283'), ('companyName', 'Microsoft'), ('ceoName', 'Satya Nadella'), ('product', 'http://www.wikidata.org/entity/Q1406'), ('productName', 'Microsoft Windows')]
# [('company', 'http://www.wikidata.org/entity/Q2283'), ('companyName', 'Microsoft'), ('ceoName', 'Satya Nadella'), ('product', 'http://www.wikidata.org/entity/Q725967'), ('productName', 'Microsoft Azure')]
# 14

# %%
#there is one product, "computer hardware", that may help us find the class related to products of a company, the other results are just the name of specific products
#let's find the class of "computer hardware"
computer_hardware = 'wd:Q3966'
q = f"""
select distinct ?class ?className where{{
wd:Q3966 wdt:P31 ?class .
# ?class <http://schema.org/name> ?className .
}}
"""
run_query(q)
# Out:
# [('class', 'http://www.wikidata.org/entity/Q11650'), ('className', 'electronics')]
# 1

# %%
#let's do that again for "electronics"
electronics = 'wd:Q11650'
q = f"""
select distinct ?class ?className where{{
wd:Q11650 wdt:P31 ?class .
# ?class <http://schema.org/name> ?className .
}}
"""
run_query(q)
# Out:
# [('class', 'http://www.wikidata.org/entity/Q11862829'), ('className', 'academic discipline')]
# [('class', 'http://www.wikidata.org/entity/Q2465832'), ('className', 'branch of science')]
# 2

# %%
#this is bringing us nowhere, maybe "computer hardware" is subclass of something more general
subclass = 'wdt:P279'
q = f"""
select distinct ?super ?name where{{
wd:Q3966 wdt:P279 ?super .
# ?super <http://schema.org/name> ?name .
}}
"""
run_query(q)
# Out:
# [('super', 'http://www.wikidata.org/entity/Q11661'), ('name', 'information technology')]
# [('super', 'http://www.wikidata.org/entity/Q2424752'), ('name', 'product')]
# [('super', 'http://www.wikidata.org/entity/Q2858615'), ('name', 'electronic machine')]
# 3

# %%
#let's try to fetch american companies and their products
product = 'wd:Q2424752'
q = f"""
select ?companyName ?productName where{{
# ?company wdt:P31 wd:Q4830453 ;
    wdt:P1056 ?product ;
    <http://schema.org/name> ?companyName ;
    wdt:P17 wd:Q30 .
# ?product wdt:P279 wd:Q2424752 ;
    <http://schema.org/name> ?productName .
    
}}
order by asc(?productName)
limit 20
"""
run_query(q)
# Out:
# [('companyName', 'Zagg'), ('productName', 'Screen protector')]
# [('companyName', 'Balsam Hill'), ('productName', 'artificial Christmas tree')]
# [('companyName', 'Timken Company'), ('productName', 'bearing')]
# [('companyName', 'H. H. Franklin Manufacturing Company'), ('productName', 'bearing')]
# [('companyName', 'Hamilton Shirts'), ('productName', 'bespoke')]
# [('companyName', 'Diversey, Inc.'), ('productName', 'cleaning product')]
# [('companyName', 'Oakley, Inc.'), ('productName', 'clothing')]
# [('companyName', 'Columbia Sportswear Company'), ('productName', 'clothing')]
# [('companyName', 'TRU-SPEC'), ('productName', 'clothing')]
# [('companyName', 'Charming Shoppes'), ('productName', 'clothing')]
# [('companyName', 'Banana Republic'), ('productName', 'clothing')]
# [('companyName', 'Warnaco Group'), ('productName', 'clothing')]
# [('companyName', 'Spanx, Inc.'), ('productName', 'clothing')]
# [('companyName', 'Vapor Apparel'), ('productName', 'clothing')]
# [('companyName', 'New Era Cap Company'), ('productName', 'clothing')]
# [('companyName', 'AND1'), ('productName', 'clothing')]
# [('companyName', 'Brine, Corp.'), ('productName', 'clothing')]
# [('companyName', 'New Balance'), ('productName', 'clothing')]
# [('companyName', 'Calvin Klein'), ('productName', 'clothing')]
# [('companyName', 'Parkwood Entertainment'), ('productName', 'clothing')]
# 20

# %%
#with the more general product class that we found, does microsoft produce software as well?
#let's get microsoft's uri
q = f"""
select distinct ?company ?companyName where{{
# ?company wdt:P31 wd:Q4830453;
    <http://schema.org/name> ?companyName .
filter regex(?companyName, 'microsoft', 'i')
}}
"""
run_query(q)
# Out:
# [('company', 'http://www.wikidata.org/entity/Q20081886'), ('companyName', 'Microsoft (Ukraine)')]
# [('company', 'http://www.wikidata.org/entity/Q2283'), ('companyName', 'Microsoft')]
# [('company', 'http://www.wikidata.org/entity/Q6840157'), ('companyName', 'Microsoft Japan')]
# [('company', 'http://www.wikidata.org/entity/Q6840192'), ('companyName', 'Microsoft Production Studios')]
# [('company', 'http://www.wikidata.org/entity/Q16538568'), ('companyName', 'Microsoft Mobile')]
# [('company', 'http://www.wikidata.org/entity/Q30273752'), ('companyName', 'Microsoft (France)')]
# [('company', 'http://www.wikidata.org/entity/Q31327320'), ('companyName', 'Microsoft (cz)')]
# [('company', 'http://www.wikidata.org/entity/Q6840202'), ('companyName', 'Microsoft Research Asia')]
# [('company', 'http://www.wikidata.org/entity/Q80054718'), ('companyName', 'Microsoft Ireland Research')]
# [('company', 'http://www.wikidata.org/entity/Q80054807'), ('companyName', 'Microsoft Global Finance')]
# [('company', 'http://www.wikidata.org/entity/Q80055035'), ('companyName', 'Microsoft Ireland Operations')]
# [('company', 'http://www.wikidata.org/entity/Q80055169'), ('companyName', 'Microsoft Online')]
# [('company', 'http://www.wikidata.org/entity/Q80055510'), ('companyName', 'Microsoft Operations')]
# [('company', 'http://www.wikidata.org/entity/Q80055723'), ('companyName', 'Microsoft Regional Sales')]
# [('company', 'http://www.wikidata.org/entity/Q958338'), ('companyName', 'Microsoft TechNet')]
# [('company', 'http://www.wikidata.org/entity/Q101569206'), ('companyName', 'Microsoft Sweden')]
# [('company', 'http://www.wikidata.org/entity/Q55454600'), ('companyName', 'Microsoft (Denmark)')]
# [('company', 'http://www.wikidata.org/entity/Q30256612'), ('companyName', 'Microsoft (Norway)')]
# [('company', 'http://www.wikidata.org/entity/Q105968540'), ('companyName', 'MICROSOFT DEVELOPMENT CENTER COPENHAGEN')]
# [('company', 'http://www.wikidata.org/entity/Q30285136'), ('companyName', 'Microsoft (Belgium)')]
# [('company', 'http://www.wikidata.org/entity/Q30273395'), ('companyName', 'Microsoft (Ireland)')]
# [('company', 'http://www.wikidata.org/entity/Q61931210'), ('companyName', 'Microsoft (Brazil)')]
# [('company', 'http://www.wikidata.org/entity/Q24943390'), ('companyName', 'Microsoft Ventures')]
# [('company', 'http://www.wikidata.org/entity/Q30272342'), ('companyName', 'Microsoft (Finland)')]
# [('company', 'http://www.wikidata.org/entity/Q30290872'), ('companyName', 'Microsoft (Portugal)')]
# 25

# %%
company_microsoft = 'wd:Q2283'
#let's see all products of microsoft
q = f"""
select distinct ?product ?productName where{{
wd:Q2283 wdt:P1056 ?product .
# ?product wdt:P279 wd:Q2424752 .
# ?product <http://schema.org/name> ?productName
}}
"""
run_query(q)
# Out:
# [('product', 'http://www.wikidata.org/entity/Q3966'), ('productName', 'computer hardware')]
# 1

# %%
#let's check visual studio's class and superclass
visual_studio = 'wd:Q134067'
q = f"""
select distinct ?class ?className ?superClass ?superClassName where{{
wd:Q134067 wdt:P31 ?class .
wd:Q134067 wdt:P279 ?superClass .
# ?class <http://schema.org/name> ?className .
# ?superClass <http://schema.org/name> ?superClassName .
}}
"""
run_query(q)
# Out:
# Empty
# 0

# %%
#let's add optionals
q = f"""
select distinct ?class ?className ?superClass ?superClassName where{{
wd:Q134067 wdt:P31 ?class .
    optional{{
        wd:Q134067 wdt:P279 ?superClass .
        # ?superClass <http://schema.org/name> ?superClassName .
    }}
# ?class <http://schema.org/name> ?className .
}}
"""
run_query(q)
# Out:
# [('class', 'http://www.wikidata.org/entity/Q13741'), ('className', 'integrated development environment')]
# 1

# %%
#this didn't help us either. the only thing i can think of is to go back to the list of properties for microsoft and search for another one
#doing this i found the property "industry", let's check that out
industry = 'wdt:P452'
#let's see the industry for some companies in the us
q = f"""
select ?companyName ?industry ?industryName where{{
# ?company wdt:P31 wd:Q4830453 ;
    wdt:P17 wd:Q30 ;
    wdt:P452 ?industry ;
    <http://schema.org/name> ?companyName .
# ?industry <http://schema.org/name> ?industryName
}}
limit 20
"""
run_query(q)
# Out:
# [('companyName', 'Lyft'), ('industry', 'http://www.wikidata.org/entity/Q41222493'), ('industryName', 'taxi service')]
# [('companyName', 'Marvel Productions'), ('industry', 'http://www.wikidata.org/entity/Q375336'), ('industryName', 'film studio')]
# [('companyName', 'Walt Disney Television'), ('industry', 'http://www.wikidata.org/entity/Q10689397'), ('industryName', 'television production company')]
# [('companyName', 'Far East Broadcasting Company'), ('industry', 'http://www.wikidata.org/entity/Q15078788'), ('industryName', 'broadcasting')]
# [('companyName', 'American Electric Power'), ('industry', 'http://www.wikidata.org/entity/Q383973'), ('industryName', 'electricity generation')]
# [('companyName', 'American Locomotive Company'), ('industry', 'http://www.wikidata.org/entity/Q4265939'), ('industryName', 'locomotive manufacturing')]
# [('companyName', 'Commodore International'), ('industry', 'http://www.wikidata.org/entity/Q581105'), ('industryName', 'consumer electronics')]
# [('companyName', 'ForgeRock'), ('industry', 'http://www.wikidata.org/entity/Q1318054'), ('industryName', 'enterprise software')]
# [('companyName', 'CA Technologies'), ('industry', 'http://www.wikidata.org/entity/Q1318054'), ('industryName', 'enterprise software')]
# [('companyName', 'Cannondale Bicycle Corporation'), ('industry', 'http://www.wikidata.org/entity/Q17018236'), ('industryName', 'bicycle industry')]
# [('companyName', 'Marathon Asset Management'), ('industry', 'http://www.wikidata.org/entity/Q105611'), ('industryName', 'hedge fund')]
# [('companyName', 'Bridgewater Associates'), ('industry', 'http://www.wikidata.org/entity/Q105611'), ('industryName', 'hedge fund')]
# [('companyName', 'Silicon Valley Sports & Entertainment'), ('industry', 'http://www.wikidata.org/entity/Q3321471'), ('industryName', 'sports marketing')]
# [('companyName', 'TJX Companies'), ('industry', 'http://www.wikidata.org/entity/Q126793'), ('industryName', 'retail')]
# [('companyName', "Sleepy's"), ('industry', 'http://www.wikidata.org/entity/Q126793'), ('industryName', 'retail')]
# [('companyName', 'Shirokiya'), ('industry', 'http://www.wikidata.org/entity/Q126793'), ('industryName', 'retail')]
# [('companyName', 'Future Shop'), ('industry', 'http://www.wikidata.org/entity/Q126793'), ('industryName', 'retail')]
# [('companyName', 'Best Buy'), ('industry', 'http://www.wikidata.org/entity/Q126793'), ('industryName', 'retail')]
# [('companyName', 'Charming Shoppes'), ('industry', 'http://www.wikidata.org/entity/Q126793'), ('industryName', 'retail')]
# [('companyName', 'CMX Cinemas'), ('industry', 'http://www.wikidata.org/entity/Q19595701'), ('industryName', 'entertainment industry')]
# 20

# %%
#let's count the number of companies in the us for each industry
q = f"""
select ?industry ?industryName (count(*) as ?total) where{{
# ?company wdt:P31 wd:Q4830453 ;
    wdt:P452 ?industry ;
    wdt:P17 wd:Q30 .
    
# ?industry <http://schema.org/name> ?industryName .
}}
group by ?industry ?industryName
limit 30
"""
run_query(q)
# Out:
# [('industry', 'http://www.wikidata.org/entity/Q219409'), ('industryName', 'venture capital'), ('total', '2')]
# [('industry', 'http://www.wikidata.org/entity/Q484847'), ('industryName', 'e-commerce'), ('total', '51')]
# [('industry', 'http://www.wikidata.org/entity/Q11650'), ('industryName', 'electronics'), ('total', '61')]
# [('industry', 'http://www.wikidata.org/entity/Q31207'), ('industryName', 'health care'), ('total', '101')]
# [('industry', 'http://www.wikidata.org/entity/Q1481411'), ('industryName', 'IT service management'), ('total', '14')]
# [('industry', 'http://www.wikidata.org/entity/Q3510521'), ('industryName', 'computer security'), ('total', '27')]
# [('industry', 'http://www.wikidata.org/entity/Q1416012'), ('industryName', 'managed care'), ('total', '6')]
# [('industry', 'http://www.wikidata.org/entity/Q775325'), ('industryName', 'transportation engineering'), ('total', '1')]
# [('industry', 'http://www.wikidata.org/entity/Q160738'), ('industryName', 'role-playing game'), ('total', '8')]
# [('industry', 'http://www.wikidata.org/entity/Q1186952'), ('industryName', 'interactive media'), ('total', '3')]
# [('industry', 'http://www.wikidata.org/entity/Q1540863'), ('industryName', 'information technology consulting'), ('total', '8')]
# [('industry', 'http://www.wikidata.org/entity/Q12752882'), ('industryName', 'cosmetics industry'), ('total', '13')]
# [('industry', 'http://www.wikidata.org/entity/Q216212'), ('industryName', 'motel'), ('total', '1')]
# [('industry', 'http://www.wikidata.org/entity/Q131734'), ('industryName', 'brewery'), ('total', '5')]
# [('industry', 'http://www.wikidata.org/entity/Q11707'), ('industryName', 'restaurant'), ('total', '51')]
# [('industry', 'http://www.wikidata.org/entity/Q1527901'), ('industryName', 'unmanned vehicle'), ('total', '1')]
# [('industry', 'http://www.wikidata.org/entity/Q43015'), ('industryName', 'finance'), ('total', '47')]
# [('industry', 'http://www.wikidata.org/entity/Q2024501'), ('industryName', 'DVD-by-mail'), ('total', '1')]
# [('industry', 'http://www.wikidata.org/entity/Q3268325'), ('industryName', 'mobile security'), ('total', '1')]
# [('industry', 'http://www.wikidata.org/entity/Q2085381'), ('industryName', 'publisher'), ('total', '7')]
# [('industry', 'http://www.wikidata.org/entity/Q181790'), ('industryName', 'composite material'), ('total', '1')]
# [('industry', 'http://www.wikidata.org/entity/Q214932'), ('industryName', 'flight simulator'), ('total', '1')]
# [('industry', 'http://www.wikidata.org/entity/Q1634416'), ('industryName', 'stock photography'), ('total', '5')]
# [('industry', 'http://www.wikidata.org/entity/Q107601756'), ('industryName', 'food and tobacco industry'), ('total', '4')]
# [('industry', 'http://www.wikidata.org/entity/Q625568'), ('industryName', 'show business'), ('total', '4')]
# [('industry', 'http://www.wikidata.org/entity/Q271588'), ('industryName', 'printmaking'), ('total', '1')]
# [('industry', 'http://www.wikidata.org/entity/Q377688'), ('industryName', 'type foundry'), ('total', '1')]
# [('industry', 'http://www.wikidata.org/entity/Q626608'), ('industryName', 'life insurance'), ('total', '9')]
# [('industry', 'http://www.wikidata.org/entity/Q811501'), ('industryName', 'construction management'), ('total', '3')]
# [('industry', 'http://www.wikidata.org/entity/Q3150593'), ('industryName', 'alcohol industry'), ('total', '2')]
# 30

# %% [markdown]
# ## Copy of goals to avoid scrolling up
#
# 1. Identify the BGP for obtaining number of employees of a company and other relevant numerical attributes
#
# 2. Identify the BGP to retrieve all companies owned by a company
#
# 3. Is there some company that owns companies in other countries?
#
# 4. Companies have different 'legal forms', compare the number of companies divided in different legal forms
#
# 5. Analyze the number of employees  and other relevant numeric attributes
#
#    5.1 What are the top-10 companies for a given attribute?
#
#    5.2 For which companies is defined some form of income or market capitalization or total assets? What is the min, max, and average in each category and country?
#
#    5.3 Which business in each country owns more businesses in other countries?

# %%
#let's start answering to the goals using all the properties found earlier
#point 1 is already complete since we know all the relevant properties. Let's list them for some companies

#employees
q = f"""
select distinct ?companyName ?employees where{{
# ?company wdt:P31 wd:Q4830453 ;
    <http://schema.org/name> ?companyName ;
    wdt:P1128 ?employees .
}}
limit 20
"""
run_query(q)
# Out:
# [('companyName', 'APM Terminals B.V'), ('employees', '20600')]
# [('companyName', 'Agrostroj Pelhřimov'), ('employees', '2456')]
# [('companyName', 'Cengage Learning'), ('employees', '5500')]
# [('companyName', 'DHL'), ('employees', '570000')]
# [('companyName', 'Elevation Partners'), ('employees', '20')]
# [('companyName', 'DNB Bank'), ('employees', '9020')]
# [('companyName', 'R. J. Reynolds Tobacco Company'), ('employees', '400000')]
# [('companyName', 'Merrill Lynch'), ('employees', '60000')]
# [('companyName', 'Gillette'), ('employees', '29000')]
# [('companyName', 'KCA DEUTAG'), ('employees', '8000')]
# [('companyName', 'Česká zbrojovka Strakonice'), ('employees', '1244')]
# [('companyName', 'Nobiskrug'), ('employees', '1000')]
# [('companyName', 'Mt.Gox'), ('employees', '19')]
# [('companyName', 'Schypke'), ('employees', '80')]
# [('companyName', 'FARYS'), ('employees', '774')]
# [('companyName', 'VeriSilicon Holdings Co., Ltd.'), ('employees', '400')]
# [('companyName', 'Remondis'), ('employees', '32000')]
# [('companyName', 'Glasmanufaktur von Poschinger'), ('employees', '23')]
# [('companyName', 'Royal Canadian Mint'), ('employees', '1280')]
# [('companyName', 'Beijing Huaqi Information Digital Technology Co., Ltd.'), ('employees', '1900')]
# 20

# %%
#assets and revenue
q = f"""
select distinct ?companyName ?assets ?revenue where{{
# ?company wdt:P31 wd:Q4830453 ;
    <http://schema.org/name> ?companyName ;
    wdt:P2403 ?assets ;
    wdt:P2139 ?revenue .
}}
limit 20
"""
run_query(q)
# Out:
# [('companyName', 'Agrostroj Pelhřimov'), ('assets', '7824063000'), ('revenue', '6186466000')]
# [('companyName', 'DNB Bank'), ('assets', '2793294000000'), ('revenue', '54857000000')]
# [('companyName', 'Merrill Lynch'), ('assets', '603000000000'), ('revenue', '20217000000')]
# [('companyName', 'Merrill Lynch'), ('assets', '603000000000'), ('revenue', '24397000000')]
# [('companyName', 'Česká zbrojovka Strakonice'), ('assets', '2165963000'), ('revenue', '1462114000')]
# [('companyName', 'Energetický a průmyslový holding'), ('assets', '13329000000'), ('revenue', '6998000000')]
# [('companyName', 'Energetický a průmyslový holding'), ('assets', '342889000000'), ('revenue', '6998000000')]
# [('companyName', 'Energetický a průmyslový holding'), ('assets', '13329000000'), ('revenue', '180024000000')]
# [('companyName', 'Energetický a průmyslový holding'), ('assets', '342889000000'), ('revenue', '180024000000')]
# [('companyName', 'AGEL'), ('assets', '10518247000'), ('revenue', '18246784000')]
# [('companyName', 'PPF'), ('assets', '2203115000'), ('revenue', '873572000')]
# [('companyName', 'MTC - invest'), ('assets', '101485000'), ('revenue', '33129000')]
# [('companyName', 'HHLA'), ('assets', '2610019000'), ('revenue', '1177700000')]
# [('companyName', 'HC Sparta Praha'), ('assets', '121697000'), ('revenue', '217616000')]
# [('companyName', 'Ant Group'), ('assets', '271558000000'), ('revenue', '120618000000')]
# [('companyName', 'Korea Aerospace Industries'), ('assets', '2933216465722'), ('revenue', '1550000000')]
# [('companyName', 'Vinci'), ('assets', '91102000000'), ('revenue', '48053000000')]
# [('companyName', '1. FK Příbram'), ('assets', '91422000'), ('revenue', '82661000')]
# [('companyName', 'Tula Arms Plant'), ('assets', '18048071000'), ('revenue', '7142712000')]
# [('companyName', 'MOL Česká republika'), ('assets', '10945322000'), ('revenue', '47992495000')]
# 20

# %%
#combining everything
q = f"""
select ?company ?companyName ?n_employees ?revenue ?assets where{{
# ?company wdt:P31 wd:Q4830453 ;
    <http://schema.org/name> ?companyName ;
    wdt:P1128 ?n_employees ;
    wdt:P2139 ?revenue ;
    wdt:P2403 ?assets .
}}
order by desc(?revenue)
limit(10)
"""
run_query(q)
# Out:
# [('company', 'http://www.wikidata.org/entity/Q20718'), ('companyName', 'Samsung Electronics'), ('n_employees', '392305'), ('revenue', '201870000000000'), ('assets', '262174300000000')]
# [('company', 'http://www.wikidata.org/entity/Q53268'), ('companyName', 'Toyota'), ('n_employees', '359542'), ('revenue', '28403118000000'), ('assets', '47427597000000')]
# [('company', 'http://www.wikidata.org/entity/Q201653'), ('companyName', 'SoftBank'), ('n_employees', '68402'), ('revenue', '9158765000000'), ('assets', '31180466000000')]
# [('company', 'http://www.wikidata.org/entity/Q53247'), ('companyName', 'Panasonic Corporation'), ('n_employees', '257533'), ('revenue', '7343707000000'), ('assets', '5982961000000')]
# [('company', 'http://www.wikidata.org/entity/Q102673'), ('companyName', 'Gazprom'), ('n_employees', '469600'), ('revenue', '6321559000000'), ('assets', '23352185000000')]
# [('company', 'http://www.wikidata.org/entity/Q1141123'), ('companyName', 'Rosneft'), ('n_employees', '334600'), ('revenue', '5757000000000'), ('assets', '15350000000000')]
# [('company', 'http://www.wikidata.org/entity/Q329347'), ('companyName', 'Lukoil'), ('n_employees', '101000'), ('revenue', '5639401000000'), ('assets', '5991579000000')]
# [('company', 'http://www.wikidata.org/entity/Q549181'), ('companyName', 'MOL Group'), ('n_employees', '24986'), ('revenue', '3553005000000'), ('assets', '4103786000000')]
# [('company', 'http://www.wikidata.org/entity/Q499071'), ('companyName', 'East Japan Railway Company'), ('n_employees', '73063'), ('revenue', '2880802000000'), ('assets', '7911115000000')]
# [('company', 'http://www.wikidata.org/entity/Q588786'), ('companyName', 'China National Petroleum Corporation'), ('n_employees', '1589508'), ('revenue', '2599417420000'), ('assets', '4034097790000')]
# 10

# %%
#we can also answer goal 2
#let's select Microsoft as owner
q = f"""
select distinct ?owned ?name where{{
wd:Q2283 wdt:P1830 ?owned .
# ?owned <http://schema.org/name> ?name ;
    wdt:P31 wd:Q4830453 .
}}
"""
run_query(q)
# Out:
# [('owned', 'http://www.wikidata.org/entity/Q3073996'), ('name', 'Xamarin')]
# [('owned', 'http://www.wikidata.org/entity/Q213660'), ('name', 'LinkedIn')]
# [('owned', 'http://www.wikidata.org/entity/Q246125'), ('name', 'Skype Technologies')]
# [('owned', 'http://www.wikidata.org/entity/Q131910'), ('name', 'Yammer')]
# [('owned', 'http://www.wikidata.org/entity/Q224599'), ('name', 'Powerset')]
# [('owned', 'http://www.wikidata.org/entity/Q31327320'), ('name', 'Microsoft (cz)')]
# [('owned', 'http://www.wikidata.org/entity/Q4048220'), ('name', 'Revolution Analytics')]
# [('owned', 'http://www.wikidata.org/entity/Q6715783'), ('name', 'MGS Mobile Gaming')]
# [('owned', 'http://www.wikidata.org/entity/Q6784797'), ('name', 'Massive Incorporated')]
# [('owned', 'http://www.wikidata.org/entity/Q958338'), ('name', 'Microsoft TechNet')]
# 10

# %%
#now let's see the country of companies owned by Microsoft
q = f"""
select distinct ?name ?countryName where{{
wd:Q2283 wdt:P1830 ?owned .
# ?owned <http://schema.org/name> ?name ;
    wdt:P31 wd:Q4830453 ;
    wdt:P17 ?country .
# ?country <http://schema.org/name> ?countryName .
}}
"""
run_query(q)
# Out:
# [('name', 'Xamarin'), ('countryName', 'United States of America')]
# [('name', 'LinkedIn'), ('countryName', 'United States of America')]
# [('name', 'Skype Technologies'), ('countryName', 'Luxembourg')]
# [('name', 'Yammer'), ('countryName', 'United States of America')]
# [('name', 'Powerset'), ('countryName', 'United States of America')]
# [('name', 'Microsoft (cz)'), ('countryName', 'Czech Republic')]
# [('name', 'Revolution Analytics'), ('countryName', 'United States of America')]
# 7

# %%
# let's try now to run the query "get (some) companies that own other companies in a different country"
q = f"""
select ?companyName ?companyCountry ?ownedCompany ?countryOfOwned where{{
# ?company wdt:P31 wd:Q4830453 ;
    <http://schema.org/name> ?companyName ;
    wdt:P17 ?country ;
    wdt:P1830 ?owned .
    
# ?owned wdt:P31 wd:Q4830453 ;
    <http://schema.org/name> ?ownedCompany ;
    wdt:P17 ?c .
    
# ?country <http://schema.org/name> ?companyCountry .
# ?c <http://schema.org/name> ?countryOfOwned .
filter(?country != ?c) .
filter(?country in (wd:Q16, wd:Q145, wd:Q30))
}}
limit(10)
"""
run_query(q)
# Out:
# [('companyName', 'Gillette'), ('companyCountry', 'United States of America'), ('ownedCompany', 'Braun'), ('countryOfOwned', 'Germany')]
# [('companyName', 'Arriva'), ('companyCountry', 'United Kingdom'), ('ownedCompany', 'Società Italiana Autoservizi'), ('countryOfOwned', 'Italy')]
# [('companyName', 'Arriva'), ('companyCountry', 'United Kingdom'), ('ownedCompany', 'SAB Autoservizi'), ('countryOfOwned', 'Italy')]
# [('companyName', 'Arriva'), ('companyCountry', 'United Kingdom'), ('ownedCompany', 'SAL Lecco'), ('countryOfOwned', 'Italy')]
# [('companyName', 'Best Buy'), ('companyCountry', 'United States of America'), ('ownedCompany', 'Future Shop'), ('countryOfOwned', 'Canada')]
# [('companyName', 'Anglo American plc'), ('companyCountry', 'United Kingdom'), ('ownedCompany', 'De Beers'), ('countryOfOwned', 'South Africa')]
# [('companyName', 'Gibson'), ('companyCountry', 'United States of America'), ('ownedCompany', 'TEAC Corporation'), ('countryOfOwned', 'Japan')]
# [('companyName', 'Sun Capital Partners'), ('companyCountry', 'United States of America'), ('ownedCompany', 'Dreams'), ('countryOfOwned', 'United Kingdom')]
# [('companyName', 'Garmin'), ('companyCountry', 'United States of America'), ('ownedCompany', 'Navigon'), ('countryOfOwned', 'Germany')]
# [('companyName', '3G Capital'), ('companyCountry', 'United States of America'), ('ownedCompany', 'Lojas Americanas'), ('countryOfOwned', 'Brazil')]
# 10

# %%
#we have found some, so goal 3 can be answered by this ask query
a = f"""
ask where{{
# ?company wdt:P31 wd:Q4830453 ;
    wdt:P1830 ?company2 ;
    wdt:P17 ?country .

# ?company2 wdt:P31 wd:Q4830453 ;
    wdt:P17 ?country2 .

filter(?country != ?country2)
}}
"""
run_ask_query(a)
# Out:
# {'head': {'link': []}, 'boolean': True}

# %%
#let's go to goal 4 now, the code for the property "legal_form" was found a while ago and it is
legal_form = 'wdt:P1454'
#let's view some legal forms, just out of curiosity
q = f"""
select distinct ?legalForm ?name where{{
# ?company wdt:P31 wd:Q4830453 ;
    wdt:P1454 ?legalForm .
# ?legalForm <http://schema.org/name> ?name
}}
limit 20
"""
run_query(q)
# Out:
# [('legalForm', 'http://www.wikidata.org/entity/Q20746571'), ('name', 'public company limited by shares')]
# [('legalForm', 'http://www.wikidata.org/entity/Q18340464'), ('name', 'sociedade anónima')]
# [('legalForm', 'http://www.wikidata.org/entity/Q2624661'), ('name', 'Sp. z o.o.')]
# [('legalForm', 'http://www.wikidata.org/entity/Q17990971'), ('name', 'public enterprise')]
# [('legalForm', 'http://www.wikidata.org/entity/Q1780031'), ('name', 'Kommanditgesellschaft')]
# [('legalForm', 'http://www.wikidata.org/entity/Q1518608'), ('name', 'limited liability company')]
# [('legalForm', 'http://www.wikidata.org/entity/Q510785'), ('name', 'association without lucrative purpose')]
# [('legalForm', 'http://www.wikidata.org/entity/Q64699475'), ('name', 'spółka akcyjna')]
# [('legalForm', 'http://www.wikidata.org/entity/Q16917171'), ('name', 'private limited company')]
# [('legalForm', 'http://www.wikidata.org/entity/Q11900271'), ('name', 'valtion liikelaitos')]
# [('legalForm', 'http://www.wikidata.org/entity/Q157031'), ('name', 'foundation')]
# [('legalForm', 'http://www.wikidata.org/entity/Q166280'), ('name', 'S.A.')]
# [('legalForm', 'http://www.wikidata.org/entity/Q422007'), ('name', 'aktiebolag')]
# [('legalForm', 'http://www.wikidata.org/entity/Q693737'), ('name', 'Aktiengesellschaft')]
# [('legalForm', 'http://www.wikidata.org/entity/Q69787585'), ('name', 'Établissement public (Luxembourg)')]
# [('legalForm', 'http://www.wikidata.org/entity/Q2624520'), ('name', 'aktieselskab')]
# [('legalForm', 'http://www.wikidata.org/entity/Q270791'), ('name', 'state-owned enterprise')]
# [('legalForm', 'http://www.wikidata.org/entity/Q6832945'), ('name', 'private company limited by shares')]
# [('legalForm', 'http://www.wikidata.org/entity/Q333920'), ('name', 'Oy')]
# [('legalForm', 'http://www.wikidata.org/entity/Q22084735'), ('name', 'Aktiengesellschaft')]
# 20

# %%
#now let's answer to goal 4, we count for each legal form the number of companies associated
q = f"""
select ?legalForm ?name (count(*) as ?howMany) where{{
# ?company wdt:P31 wd:Q4830453 ;
    wdt:P1454 ?legalForm .
# ?legalForm <http://schema.org/name> ?name .
}}
group by ?name ?legalForm
order by desc (?howMany)
"""
run_query(q)
# Out:
# [('legalForm', 'http://www.wikidata.org/entity/Q15646299'), ('name', 'společnost s ručením omezeným'), ('howMany', '13059')]
# [('legalForm', 'http://www.wikidata.org/entity/Q3742494'), ('name', 'akciová společnost'), ('howMany', '5551')]
# [('legalForm', 'http://www.wikidata.org/entity/Q134161'), ('name', 'joint-stock company'), ('howMany', '5168')]
# [('legalForm', 'http://www.wikidata.org/entity/Q460178'), ('name', 'GmbH'), ('howMany', '2823')]
# [('legalForm', 'http://www.wikidata.org/entity/Q15649019'), ('name', 'Spoločnosť s ručením obmedzeným'), ('howMany', '2302')]
# [('legalForm', 'http://www.wikidata.org/entity/Q891723'), ('name', 'public company'), ('howMany', '1407')]
# [('legalForm', 'http://www.wikidata.org/entity/Q15042660'), ('name', 'aksjeselskap'), ('howMany', '1312')]
# [('legalForm', 'http://www.wikidata.org/entity/Q1480166'), ('name', 'kabushiki gaisha'), ('howMany', '1228')]
# [('legalForm', 'http://www.wikidata.org/entity/Q166280'), ('name', 'S.A.'), ('howMany', '1132')]
# [('legalForm', 'http://www.wikidata.org/entity/Q897103'), ('name', 'GmbH & Co. KG'), ('howMany', '1127')]
# [('legalForm', 'http://www.wikidata.org/entity/Q18624259'), ('name', 'private limited liability company'), ('howMany', '1023')]
# [('legalForm', 'http://www.wikidata.org/entity/Q1589009'), ('name', 'privately held company'), ('howMany', '968')]
# [('legalForm', 'http://www.wikidata.org/entity/Q422062'), ('name', 'Aktiengesellschaft'), ('howMany', '846')]
# [('legalForm', 'http://www.wikidata.org/entity/Q693737'), ('name', 'Aktiengesellschaft'), ('howMany', '841')]
# [('legalForm', 'http://www.wikidata.org/entity/Q77872838'), ('name', 'akciová spoločnosť'), ('howMany', '838')]
# [('legalForm', 'http://www.wikidata.org/entity/Q13641190'), ('name', 'open joint-stock company'), ('howMany', '586')]
# [('legalForm', 'http://www.wikidata.org/entity/Q6832945'), ('name', 'private company limited by shares'), ('howMany', '566')]
# [('legalForm', 'http://www.wikidata.org/entity/Q654502'), ('name', 'Société par actions simplifiée'), ('howMany', '554')]
# [('legalForm', 'http://www.wikidata.org/entity/Q15829892'), ('name', 'Gesellschaft mit beschränkter Haftung'), ('howMany', '455')]
# [('legalForm', 'http://www.wikidata.org/entity/Q4539'), ('name', 'cooperative'), ('howMany', '435')]
# [('legalForm', 'http://www.wikidata.org/entity/Q1518609'), ('name', 'Gesellschaft mit beschränkter Haftung'), ('howMany', '412')]
# [('legalForm', 'http://www.wikidata.org/entity/Q15648878'), ('name', 'S.r.l.'), ('howMany', '385')]
# [('legalForm', 'http://www.wikidata.org/entity/Q149789'), ('name', 'limited liability company'), ('howMany', '377')]
# [('legalForm', 'http://www.wikidata.org/entity/Q2624520'), ('name', 'aktieselskab'), ('howMany', '340')]
# [('legalForm', 'http://www.wikidata.org/entity/Q5225895'), ('name', 'public limited company'), ('howMany', '329')]
# [('legalForm', 'http://www.wikidata.org/entity/Q3742388'), ('name', 'società per azioni'), ('howMany', '318')]
# [('legalForm', 'http://www.wikidata.org/entity/Q279014'), ('name', 'Societas Europaea'), ('howMany', '307')]
# [('legalForm', 'http://www.wikidata.org/entity/Q422007'), ('name', 'aktiebolag'), ('howMany', '306')]
# [('legalForm', 'http://www.wikidata.org/entity/Q791974'), ('name', 'mutual fund'), ('howMany', '269')]
# [('legalForm', 'http://www.wikidata.org/entity/Q16917171'), ('name', 'private limited company'), ('howMany', '254')]
# [('legalForm', 'http://www.wikidata.org/entity/Q17375963'), ('name', 'Besloten vennootschap'), ('howMany', '250')]
# [('legalForm', 'http://www.wikidata.org/entity/Q18195767'), ('name', 'société anonyme'), ('howMany', '238')]
# [('legalForm', 'http://www.wikidata.org/entity/Q333920'), ('name', 'Oy'), ('howMany', '235')]
# [('legalForm', 'http://www.wikidata.org/entity/Q270791'), ('name', 'state-owned enterprise'), ('howMany', '221')]
# [('legalForm', 'http://www.wikidata.org/entity/Q783794'), ('name', 'company'), ('howMany', '211')]
# [('legalForm', 'http://www.wikidata.org/entity/Q54943230'), ('name', 'public limited company'), ('howMany', '203')]
# [('legalForm', 'http://www.wikidata.org/entity/Q1517904'), ('name', 'closed joint-stock company'), ('howMany', '189')]
# [('legalForm', 'http://www.wikidata.org/entity/Q2624661'), ('name', 'Sp. z o.o.'), ('howMany', '186')]
# [('legalForm', 'http://www.wikidata.org/entity/Q1436139'), ('name', 'Naamloze vennootschap'), ('howMany', '184')]
# [('legalForm', 'http://www.wikidata.org/entity/Q33685'), ('name', 'limited company'), ('howMany', '184')]
# [('legalForm', 'http://www.wikidata.org/entity/Q658255'), ('name', 'subsidiary'), ('howMany', '175')]
# [('legalForm', 'http://www.wikidata.org/entity/Q96109123'), ('name', 'jednoduchá spoločnosť na akcie'), ('howMany', '170')]
# [('legalForm', 'http://www.wikidata.org/entity/Q56868012'), ('name', 'Kft.'), ('howMany', '159')]
# [('legalForm', 'http://www.wikidata.org/entity/Q48204'), ('name', 'voluntary organization'), ('howMany', '155')]
# [('legalForm', 'http://www.wikidata.org/entity/Q875765'), ('name', 'Aktiengesellschaft'), ('howMany', '150')]
# [('legalForm', 'http://www.wikidata.org/entity/Q167037'), ('name', 'corporation'), ('howMany', '136')]
# [('legalForm', 'http://www.wikidata.org/entity/Q56475875'), ('name', 'A natural person doing business according to the Trade Licensing Act not registered in the Commercial Register'), ('howMany', '134')]
# [('legalForm', 'http://www.wikidata.org/entity/Q1780029'), ('name', 'Kommanditgesellschaft'), ('howMany', '126')]
# [('legalForm', 'http://www.wikidata.org/entity/Q422053'), ('name', 'NV/SA'), ('howMany', '120')]
# [('legalForm', 'http://www.wikidata.org/entity/Q422074'), ('name', 'corporation'), ('howMany', '113')]
# [('legalForm', 'http://www.wikidata.org/entity/Q61747587'), ('name', 'spolek'), ('howMany', '112')]
# [('legalForm', 'http://www.wikidata.org/entity/Q21191682'), ('name', 'ООО'), ('howMany', '102')]
# [('legalForm', 'http://www.wikidata.org/entity/Q7257282'), ('name', 'public-benefit corporation'), ('howMany', '93')]
# [('legalForm', 'http://www.wikidata.org/entity/Q19343649'), ('name', 'private limited liability company'), ('howMany', '89')]
# [('legalForm', 'http://www.wikidata.org/entity/Q57655560'), ('name', 'U.S. corporation'), ('howMany', '87')]
# [('legalForm', 'http://www.wikidata.org/entity/Q14942889'), ('name', 'allmennaksjeselskap'), ('howMany', '87')]
# [('legalForm', 'http://www.wikidata.org/entity/Q2531989'), ('name', 'Volkseigener Betrieb'), ('howMany', '81')]
# [('legalForm', 'http://www.wikidata.org/entity/Q56489561'), ('name', 'sociedad anónima'), ('howMany', '81')]
# [('legalForm', 'http://www.wikidata.org/entity/Q15649047'), ('name', 'Anpartsselskab'), ('howMany', '79')]
# [('legalForm', 'http://www.wikidata.org/entity/Q165758'), ('name', 'Kommanditgesellschaft'), ('howMany', '78')]
# [('legalForm', 'http://www.wikidata.org/entity/Q1588658'), ('name', 'limited liability partnership'), ('howMany', '69')]
# [('legalForm', 'http://www.wikidata.org/entity/Q15856579'), ('name', 'Akcinė bendrovė'), ('howMany', '61')]
# [('legalForm', 'http://www.wikidata.org/entity/Q97174998'), ('name', 'limited liability company'), ('howMany', '61')]
# [('legalForm', 'http://www.wikidata.org/entity/Q43751707'), ('name', 'komanditní společnost'), ('howMany', '60')]
# [('legalForm', 'http://www.wikidata.org/entity/Q3742992'), ('name', 'Anonim Şirket'), ('howMany', '59')]
# [('legalForm', 'http://www.wikidata.org/entity/Q43750924'), ('name', 'otevřený podílový fond'), ('howMany', '53')]
# [('legalForm', 'http://www.wikidata.org/entity/Q5349747'), ('name', 'Eingetragene Genossenschaft'), ('howMany', '50')]
# [('legalForm', 'http://www.wikidata.org/entity/Q1500859'), ('name', 'Gemeinnützige GmbH'), ('howMany', '49')]
# [('legalForm', 'http://www.wikidata.org/entity/Q15648901'), ('name', 'S.L.'), ('howMany', '49')]
# [('legalForm', 'http://www.wikidata.org/entity/Q12057785'), ('name', 'svěřenský fond'), ('howMany', '47')]
# [('legalForm', 'http://www.wikidata.org/entity/Q646164'), ('name', 'general partnership'), ('howMany', '45')]
# [('legalForm', 'http://www.wikidata.org/entity/Q96782360'), ('name', 'nadace'), ('howMany', '44')]
# [('legalForm', 'http://www.wikidata.org/entity/Q10379632'), ('name', 'Société à responsabilité limitée'), ('howMany', '43')]
# [('legalForm', 'http://www.wikidata.org/entity/Q1389604'), ('name', 'unitary enterprise'), ('howMany', '42')]
# [('legalForm', 'http://www.wikidata.org/entity/Q88537331'), ('name', 'Delaware corporation'), ('howMany', '42')]
# [('legalForm', 'http://www.wikidata.org/entity/Q154954'), ('name', 'natural person'), ('howMany', '42')]
# [('legalForm', 'http://www.wikidata.org/entity/Q49168310'), ('name', 'Société Anonyme'), ('howMany', '42')]
# [('legalForm', 'http://www.wikidata.org/entity/Q489209'), ('name', 'joint venture'), ('howMany', '41')]
# [('legalForm', 'http://www.wikidata.org/entity/Q30056758'), ('name', 'julkinen osakeyhtiö'), ('howMany', '40')]
# [('legalForm', 'http://www.wikidata.org/entity/Q955214'), ('name', 'mutual organization'), ('howMany', '39')]
# [('legalForm', 'http://www.wikidata.org/entity/Q19278985'), ('name', 'sole proprietorship in Germany'), ('howMany', '39')]
# [('legalForm', 'http://www.wikidata.org/entity/Q19340991'), ('name', 'Offene Handelsgesellschaft'), ('howMany', '38')]
# [('legalForm', 'http://www.wikidata.org/entity/Q909695'), ('name', 'limited partnership'), ('howMany', '37')]
# [('legalForm', 'http://www.wikidata.org/entity/Q59554118'), ('name', 'samvirkeforetak'), ('howMany', '37')]
# [('legalForm', 'http://www.wikidata.org/entity/Q15091621'), ('name', 'société à responsabilité limitée'), ('howMany', '36')]
# [('legalForm', 'http://www.wikidata.org/entity/Q12041908'), ('name', 'obecně prospěšná společnost'), ('howMany', '34')]
# [('legalForm', 'http://www.wikidata.org/entity/Q18340464'), ('name', 'sociedade anónima'), ('howMany', '34')]
# [('legalForm', 'http://www.wikidata.org/entity/Q3488571'), ('name', 'société par actions simplifiée unipersonnelle'), ('howMany', '33')]
# [('legalForm', 'http://www.wikidata.org/entity/Q43749575'), ('name', 'veřejná obchodní společnost'), ('howMany', '31')]
# [('legalForm', 'http://www.wikidata.org/entity/Q728646'), ('name', 'partnership'), ('howMany', '31')]
# [('legalForm', 'http://www.wikidata.org/entity/Q18631232'), ('name', 'foundation'), ('howMany', '30')]
# [('legalForm', 'http://www.wikidata.org/entity/Q219577'), ('name', 'holding company'), ('howMany', '28')]
# [('legalForm', 'http://www.wikidata.org/entity/Q16917889'), ('name', 'státní podnik'), ('howMany', '28')]
# [('legalForm', 'http://www.wikidata.org/entity/Q157031'), ('name', 'foundation'), ('howMany', '28')]
# [('legalForm', 'http://www.wikidata.org/entity/Q3963777'), ('name', 'società consortile'), ('howMany', '26')]
# [('legalForm', 'http://www.wikidata.org/entity/Q104177452'), ('name', 'open joint-stock company'), ('howMany', '24')]
# [('legalForm', 'http://www.wikidata.org/entity/Q2085381'), ('name', 'publisher'), ('howMany', '22')]
# [('legalForm', 'http://www.wikidata.org/entity/Q67207116'), ('name', 'Anstalt des öffentlichen Rechts'), ('howMany', '22')]
# [('legalForm', 'http://www.wikidata.org/entity/Q422069'), ('name', 'Limited Company'), ('howMany', '21')]
# [('legalForm', 'http://www.wikidata.org/entity/Q837619'), ('name', 'Kommanditgesellschaft auf Aktien'), ('howMany', '21')]
# [('legalForm', 'http://www.wikidata.org/entity/Q12144057'), ('name', 'private joint stock company'), ('howMany', '21')]
# [('legalForm', 'http://www.wikidata.org/entity/Q10861788'), ('name', 'association of legal entities'), ('howMany', '20')]
# [('legalForm', 'http://www.wikidata.org/entity/Q448535'), ('name', 'GbR'), ('howMany', '20')]
# [('legalForm', 'http://www.wikidata.org/entity/Q1532883'), ('name', 'GmbH & Co. KGaA'), ('howMany', '19')]
# [('legalForm', 'http://www.wikidata.org/entity/Q22130673'), ('name', 'general incorporated association'), ('howMany', '19')]
# [('legalForm', 'http://www.wikidata.org/entity/Q695318'), ('name', 'mutual insurance'), ('howMany', '19')]
# [('legalForm', 'http://www.wikidata.org/entity/Q12042877'), ('name', 'organisational unit of the state'), ('howMany', '19')]
# [('legalForm', 'http://www.wikidata.org/entity/Q163740'), ('name', 'nonprofit organization'), ('howMany', '19')]
# [('legalForm', 'http://www.wikidata.org/entity/Q64699475'), ('name', 'spółka akcyjna'), ('howMany', '19')]
# [('legalForm', 'http://www.wikidata.org/entity/Q2912172'), ('name', 'sole proprietorship'), ('howMany', '18')]
# [('legalForm', 'http://www.wikidata.org/entity/Q12041652'), ('name', 'národní podnik'), ('howMany', '18')]
# [('legalForm', 'http://www.wikidata.org/entity/Q89651843'), ('name', 'Anstalt des öffentlichen Rechts'), ('howMany', '18')]
# [('legalForm', 'http://www.wikidata.org/entity/Q1518608'), ('name', 'limited liability company'), ('howMany', '18')]
# [('legalForm', 'http://www.wikidata.org/entity/Q7448819'), ('name', 'ansvarlig selskap med delt ansvar'), ('howMany', '16')]
# [('legalForm', 'http://www.wikidata.org/entity/Q1307538'), ('name', 'Eingetragener Kaufmann'), ('howMany', '16')]
# [('legalForm', 'http://www.wikidata.org/entity/Q56487597'), ('name', 'evidovaná církevní právnická osoba'), ('howMany', '15')]
# [('legalForm', 'http://www.wikidata.org/entity/Q1555574'), ('name', 'besloten vennootschap met beperkte aansprakelijkheid'), ('howMany', '15')]
# [('legalForm', 'http://www.wikidata.org/entity/Q97063639'), ('name', 'private company limited by shares'), ('howMany', '15')]
# [('legalForm', 'http://www.wikidata.org/entity/Q1780031'), ('name', 'Kommanditgesellschaft'), ('howMany', '15')]
# [('legalForm', 'http://www.wikidata.org/entity/Q19823288'), ('name', 'Kommanditgesellschaft auf Aktien'), ('howMany', '15')]
# [('legalForm', 'http://www.wikidata.org/entity/Q5189488'), ('name', 'Crown corporation of Canada'), ('howMany', '14')]
# [('legalForm', 'http://www.wikidata.org/entity/Q510785'), ('name', 'association without lucrative purpose'), ('howMany', '14')]
# [('legalForm', 'http://www.wikidata.org/entity/Q50173563'), ('name', 'sociedade anônima'), ('howMany', '14')]
# [('legalForm', 'http://www.wikidata.org/entity/Q16969092'), ('name', 'enkeltpersonforetak'), ('howMany', '14')]
# [('legalForm', 'http://www.wikidata.org/entity/Q11513034'), ('name', 'association under the French law of 1901'), ('howMany', '14')]
# [('legalForm', 'http://www.wikidata.org/entity/Q6467378'), ('name', 'Labour Bank'), ('howMany', '13')]
# [('legalForm', 'http://www.wikidata.org/entity/Q12055643'), ('name', 'společenství vlastníků jednotek'), ('howMany', '13')]
# [('legalForm', 'http://www.wikidata.org/entity/Q486547'), ('name', 'Shinkin bank'), ('howMany', '13')]
# [('legalForm', 'http://www.wikidata.org/entity/Q11985292'), ('name', 'evidovaná právnická osoba církve a náboženské společnosti'), ('howMany', '13')]
# [('legalForm', 'http://www.wikidata.org/entity/Q745877'), ('name', 'credit union'), ('howMany', '13')]
# [('legalForm', 'http://www.wikidata.org/entity/Q9299236'), ('name', 'registered association'), ('howMany', '13')]
# [('legalForm', 'http://www.wikidata.org/entity/Q105162507'), ('name', 'Registered Society'), ('howMany', '13')]
# [('legalForm', 'http://www.wikidata.org/entity/Q2348856'), ('name', 'Stiftung & Co. KG'), ('howMany', '13')]
# [('legalForm', 'http://www.wikidata.org/entity/Q20057863'), ('name', 'endowment fund'), ('howMany', '12')]
# [('legalForm', 'http://www.wikidata.org/entity/Q15839592'), ('name', 'Partnerschaftsgesellschaft mit beschränkter Berufshaftung'), ('howMany', '12')]
# [('legalForm', 'http://www.wikidata.org/entity/Q56855687'), ('name', 'Perseroan Terbatas'), ('howMany', '12')]
# [('legalForm', 'http://www.wikidata.org/entity/Q29368833'), ('name', 'Australian Proprietary Company, Limited By Shares'), ('howMany', '12')]
# [('legalForm', 'http://www.wikidata.org/entity/Q85740306'), ('name', 'public limited company'), ('howMany', '12')]
# [('legalForm', 'http://www.wikidata.org/entity/Q21763580'), ('name', 'Družba z omejeno odgovornostjo'), ('howMany', '12')]
# [('legalForm', 'http://www.wikidata.org/entity/Q614084'), ('name', 'consumer cooperative'), ('howMany', '12')]
# [('legalForm', 'http://www.wikidata.org/entity/Q17103304'), ('name', 'sparebank'), ('howMany', '11')]
# [('legalForm', 'http://www.wikidata.org/entity/Q67583888'), ('name', 'transformovaný fond'), ('howMany', '10')]
# [('legalForm', 'http://www.wikidata.org/entity/Q43754338'), ('name', 'účastnický fond'), ('howMany', '10')]
# [('legalForm', 'http://www.wikidata.org/entity/Q2374515'), ('name', 'affiliate'), ('howMany', '10')]
# [('legalForm', 'http://www.wikidata.org/entity/Q1185713'), ('name', 'yūgen gaisha'), ('howMany', '10')]
# [('legalForm', 'http://www.wikidata.org/entity/Q206361'), ('name', 'concern'), ('howMany', '10')]
# [('legalForm', 'http://www.wikidata.org/entity/Q63439508'), ('name', 'Sendirian Berhad'), ('howMany', '10')]
# [('legalForm', 'http://www.wikidata.org/entity/Q15734684'), ('name', 'Körperschaft des öffentlichen Rechts'), ('howMany', '10')]
# [('legalForm', 'http://www.wikidata.org/entity/Q778575'), ('name', 'conglomerate'), ('howMany', '10')]
# [('legalForm', 'http://www.wikidata.org/entity/Q20746571'), ('name', 'public company limited by shares'), ('howMany', '10')]
# [('legalForm', 'http://www.wikidata.org/entity/Q18631225'), ('name', 'Stiftung'), ('howMany', '9')]
# [('legalForm', 'http://www.wikidata.org/entity/Q94279510'), ('name', 'Genossenschaft'), ('howMany', '9')]
# [('legalForm', 'http://www.wikidata.org/entity/Q6046818'), ('name', 'interkommunalt selskap'), ('howMany', '9')]
# [('legalForm', 'http://www.wikidata.org/entity/Q60675944'), ('name', 'sociedad anónima'), ('howMany', '8')]
# [('legalForm', 'http://www.wikidata.org/entity/Q4770808'), ('name', 'ansvarlig selskap med solidarisk ansvar'), ('howMany', '8')]
# [('legalForm', 'http://www.wikidata.org/entity/Q3055265'), ('name', 'single member limited liability company'), ('howMany', '8')]
# [('legalForm', 'http://www.wikidata.org/entity/Q334453'), ('name', 'division'), ('howMany', '8')]
# [('legalForm', 'http://www.wikidata.org/entity/Q6428421'), ('name', 'kommunalt foretak'), ('howMany', '8')]
# [('legalForm', 'http://www.wikidata.org/entity/Q33134157'), ('name', 'Gesellschaft bürgerlichen Rechts'), ('howMany', '8')]
# [('legalForm', 'http://www.wikidata.org/entity/Q1395324'), ('name', 'family business'), ('howMany', '8')]
# [('legalForm', 'http://www.wikidata.org/entity/Q51885892'), ('name', 'S.L.U.'), ('howMany', '8')]
# [('legalForm', 'http://www.wikidata.org/entity/Q13100008'), ('name', 'društvo sa ograničenom odgovornošću'), ('howMany', '8')]
# [('legalForm', 'http://www.wikidata.org/entity/Q99300738'), ('name', 'Société Anonyme Monégasque'), ('howMany', '7')]
# [('legalForm', 'http://www.wikidata.org/entity/Q104438803'), ('name', 'limited liability company'), ('howMany', '7')]
# [('legalForm', 'http://www.wikidata.org/entity/Q19252952'), ('name', 'associated company'), ('howMany', '7')]
# [('legalForm', 'http://www.wikidata.org/entity/Q194166'), ('name', 'consortium'), ('howMany', '7')]
# [('legalForm', 'http://www.wikidata.org/entity/Q1109313'), ('name', 'società per azioni unipersonale'), ('howMany', '7')]
# [('legalForm', 'http://www.wikidata.org/entity/Q60732047'), ('name', 'CO. Ltd.'), ('howMany', '7')]
# [('legalForm', 'http://www.wikidata.org/entity/Q103536064'), ('name', 'cooperative'), ('howMany', '7')]
# [('legalForm', 'http://www.wikidata.org/entity/Q104156895'), ('name', 'limited liability company'), ('howMany', '7')]
# [('legalForm', 'http://www.wikidata.org/entity/Q5621421'), ('name', 'private company'), ('howMany', '7')]
# [('legalForm', 'http://www.wikidata.org/entity/Q21980538'), ('name', 'commercial organization'), ('howMany', '7')]
# [('legalForm', 'http://www.wikidata.org/entity/Q51802864'), ('name', 'C.A.'), ('howMany', '7')]
# [('legalForm', 'http://www.wikidata.org/entity/Q21268738'), ('name', 'governmental administrative unit in Denmark'), ('howMany', '7')]
# [('legalForm', 'http://www.wikidata.org/entity/Q98895450'), ('name', 'public limited company with board of directors'), ('howMany', '7')]
# [('legalForm', 'http://www.wikidata.org/entity/Q3178478'), ('name', 'incorporation'), ('howMany', '7')]
# [('legalForm', 'http://www.wikidata.org/entity/Q6881511'), ('name', 'enterprise'), ('howMany', '6')]
# [('legalForm', 'http://www.wikidata.org/entity/Q4830453'), ('name', 'business'), ('howMany', '6')]
# [('legalForm', 'http://www.wikidata.org/entity/Q22084735'), ('name', 'Aktiengesellschaft'), ('howMany', '6')]
# [('legalForm', 'http://www.wikidata.org/entity/Q1941618'), ('name', 'mobile network operator'), ('howMany', '6')]
# [('legalForm', 'http://www.wikidata.org/entity/Q20658380'), ('name', 'SE & Co. KG'), ('howMany', '6')]
# [('legalForm', 'http://www.wikidata.org/entity/Q17326725'), ('name', 'business group'), ('howMany', '6')]
# [('legalForm', 'http://www.wikidata.org/entity/Q4571663'), ('name', 'Foreign corporation registered in Norway'), ('howMany', '6')]
# [('legalForm', 'http://www.wikidata.org/entity/Q699386'), ('name', 'statutory corporation'), ('howMany', '6')]
# [('legalForm', 'http://www.wikidata.org/entity/Q197952'), ('name', 'corporate group'), ('howMany', '6')]
# [('legalForm', 'http://www.wikidata.org/entity/Q563787'), ('name', 'health maintenance organization'), ('howMany', '6')]
# [('legalForm', 'http://www.wikidata.org/entity/Q23000060'), ('name', 'dansk erhvervsdrivende fond'), ('howMany', '6')]
# [('legalForm', 'http://www.wikidata.org/entity/Q129238'), ('name', 'startup company'), ('howMany', '5')]
# [('legalForm', 'http://www.wikidata.org/entity/Q104177462'), ('name', 'closed joint-stock company'), ('howMany', '5')]
# [('legalForm', 'http://www.wikidata.org/entity/Q3277997'), ('name', 'cooperative bank'), ('howMany', '5')]
# [('legalForm', 'http://www.wikidata.org/entity/Q17990971'), ('name', 'public enterprise'), ('howMany', '5')]
# [('legalForm', 'http://www.wikidata.org/entity/Q1825483'), ('name', 'Limited & Co. KG'), ('howMany', '5')]
# [('legalForm', 'http://www.wikidata.org/entity/Q11424358'), ('name', 'Japanese Regional Company'), ('howMany', '5')]
# [('legalForm', 'http://www.wikidata.org/entity/Q11392112'), ('name', 'Kōsha'), ('howMany', '5')]
# [('legalForm', 'http://www.wikidata.org/entity/Q219407'), ('name', 'Ponzi scheme'), ('howMany', '5')]
# [('legalForm', 'http://www.wikidata.org/entity/Q25099037'), ('name', 'special district'), ('howMany', '5')]
# [('legalForm', 'http://www.wikidata.org/entity/Q7257985'), ('name', 'public service company'), ('howMany', '5')]
# [('legalForm', 'http://www.wikidata.org/entity/Q11570722'), ('name', 'tokurēyūgen gaisha'), ('howMany', '5')]
# [('legalForm', 'http://www.wikidata.org/entity/Q18226900'), ('name', 'Joint stock company'), ('howMany', '5')]
# [('legalForm', 'http://www.wikidata.org/entity/Q3591583'), ('name', 'établissement public à caractère industriel et commercial'), ('howMany', '5')]
# [('legalForm', 'http://www.wikidata.org/entity/Q40890107'), ('name', 'municipal enterprise'), ('howMany', '5')]
# [('legalForm', 'http://www.wikidata.org/entity/Q20180983'), ('name', 'Kompanie'), ('howMany', '5')]
# [('legalForm', 'http://www.wikidata.org/entity/Q1303046'), ('name', 'Eigenbetrieb'), ('howMany', '5')]
# [('legalForm', 'http://www.wikidata.org/entity/Q75715216'), ('name', 'società in accomandita semplice'), ('howMany', '5')]
# [('legalForm', 'http://www.wikidata.org/entity/Q16901839'), ('name', 'societate cu răspundere limitată'), ('howMany', '5')]
# [('legalForm', 'http://www.wikidata.org/entity/Q43752985'), ('name', 'uzavřený podílový fond'), ('howMany', '5')]
# [('legalForm', 'http://www.wikidata.org/entity/Q4086495'), ('name', 'startup accelerator'), ('howMany', '4')]
# [('legalForm', 'http://www.wikidata.org/entity/Q11448283'), ('name', 'incorporated educational institution'), ('howMany', '4')]
# [('legalForm', 'http://www.wikidata.org/entity/Q20659907'), ('name', 'AG & Co. KG'), ('howMany', '4')]
# [('legalForm', 'http://www.wikidata.org/entity/Q18214700'), ('name', 'public institution'), ('howMany', '4')]
# [('legalForm', 'http://www.wikidata.org/entity/Q12301349'), ('name', 'Andelsselskab med begrænset ansvar'), ('howMany', '4')]
# [('legalForm', 'http://www.wikidata.org/entity/Q1562410'), ('name', 'gōdō gaisha'), ('howMany', '4')]
# [('legalForm', 'http://www.wikidata.org/entity/Q12782082'), ('name', 'state corporation (Russia)'), ('howMany', '4')]
# [('legalForm', 'http://www.wikidata.org/entity/Q1132207'), ('name', 'business incubator'), ('howMany', '4')]
# [('legalForm', 'http://www.wikidata.org/entity/Q2498526'), ('name', 'Entrepreneurial company (Germany)'), ('howMany', '4')]
# [('legalForm', 'http://www.wikidata.org/entity/Q20665848'), ('name', 'GmbH & Co. OHG'), ('howMany', '4')]
# [('legalForm', 'http://www.wikidata.org/entity/Q20658388'), ('name', 'SE & Co. KGaA'), ('howMany', '4')]
# [('legalForm', 'http://www.wikidata.org/entity/Q18127'), ('name', 'record label'), ('howMany', '4')]
# [('legalForm', 'http://www.wikidata.org/entity/Q53828709'), ('name', 'cooperative'), ('howMany', '4')]
# [('legalForm', 'http://www.wikidata.org/entity/Q1582023'), ('name', 'Partnerschaftsgesellschaft'), ('howMany', '4')]
# [('legalForm', 'http://www.wikidata.org/entity/Q7448816'), ('name', 'selskap med begrenset ansvar'), ('howMany', '4')]
# [('legalForm', 'http://www.wikidata.org/entity/Q19688219'), ('name', 'shared interest cooperative enterprise'), ('howMany', '3')]
# [('legalForm', 'http://www.wikidata.org/entity/Q79913'), ('name', 'non-governmental organization'), ('howMany', '3')]
# [('legalForm', 'http://www.wikidata.org/entity/Q19605764'), ('name', 'stichting'), ('howMany', '3')]
# [('legalForm', 'http://www.wikidata.org/entity/Q1430364'), ('name', 'business with mixed revenue streams'), ('howMany', '3')]
# [('legalForm', 'http://www.wikidata.org/entity/Q52148241'), ('name', 'Public Interest Incorporated Associations'), ('howMany', '3')]
# [('legalForm', 'http://www.wikidata.org/entity/Q11571013'), ('name', 'Specially designated public corporation'), ('howMany', '3')]
# [('legalForm', 'http://www.wikidata.org/entity/Q1518730'), ('name', 'corporate law in the United States'), ('howMany', '3')]
# [('legalForm', 'http://www.wikidata.org/entity/Q17084016'), ('name', 'nonprofit corporation'), ('howMany', '3')]
# [('legalForm', 'http://www.wikidata.org/entity/Q161726'), ('name', 'multinational corporation'), ('howMany', '3')]
# [('legalForm', 'http://www.wikidata.org/entity/Q4571771'), ('name', 'statsforetak'), ('howMany', '3')]
# [('legalForm', 'http://www.wikidata.org/entity/Q95678620'), ('name', 'forening/lag/innretning'), ('howMany', '3')]
# [('legalForm', 'http://www.wikidata.org/entity/Q2178147'), ('name', 'trade association'), ('howMany', '3')]
# [('legalForm', 'http://www.wikidata.org/entity/Q1780034'), ('name', 'Kommanditgesellschaft'), ('howMany', '3')]
# [('legalForm', 'http://www.wikidata.org/entity/Q56868285'), ('name', 'South African Proprietary Limited Company'), ('howMany', '3')]
# [('legalForm', 'http://www.wikidata.org/entity/Q292704'), ('name', 'AG & Co. KGaA'), ('howMany', '3')]
# [('legalForm', 'http://www.wikidata.org/entity/Q48929775'), ('name', 'società consortile per azioni'), ('howMany', '3')]
# [('legalForm', 'http://www.wikidata.org/entity/Q57697037'), ('name', 'cooperativa'), ('howMany', '3')]
# [('legalForm', 'http://www.wikidata.org/entity/Q12592379'), ('name', 'Public Institutions Policy Bureau'), ('howMany', '3')]
# [('legalForm', 'http://www.wikidata.org/entity/Q56447357'), ('name', 'school legal entity'), ('howMany', '3')]
# [('legalForm', 'http://www.wikidata.org/entity/Q368290'), ('name', 'film distributor'), ('howMany', '3')]
# [('legalForm', 'http://www.wikidata.org/entity/Q6516200'), ('name', 'private company limited by guarantee'), ('howMany', '3')]
# [('legalForm', 'http://www.wikidata.org/entity/Q21191012'), ('name', 'fylkeskommunalt foretak'), ('howMany', '3')]
# [('legalForm', 'http://www.wikidata.org/entity/Q697852'), ('name', 'real estate investment trust'), ('howMany', '3')]
# [('legalForm', 'http://www.wikidata.org/entity/Q15911314'), ('name', 'association'), ('howMany', '3')]
# [('legalForm', 'http://www.wikidata.org/entity/Q10480691'), ('name', 'Economic Association'), ('howMany', '3')]
# [('legalForm', 'http://www.wikidata.org/entity/Q79447245'), ('name', 'real estate bank'), ('howMany', '3')]
# [('legalForm', 'http://www.wikidata.org/entity/Q15343039'), ('name', 'établissement public'), ('howMany', '3')]
# [('legalForm', 'http://www.wikidata.org/entity/Q708676'), ('name', 'charitable organization'), ('howMany', '3')]
# [('legalForm', 'http://www.wikidata.org/entity/Q18325436'), ('name', '501(c)(3) organization'), ('howMany', '3')]
# [('legalForm', 'http://www.wikidata.org/entity/Q375336'), ('name', 'film studio'), ('howMany', '3')]
# [('legalForm', 'http://www.wikidata.org/entity/Q17050380'), ('name', 'kommanditselskab'), ('howMany', '3')]
# [('legalForm', 'http://www.wikidata.org/entity/Q835400'), ('name', 'combine'), ('howMany', '3')]
# [('legalForm', 'http://www.wikidata.org/entity/Q570208'), ('name', 'public-law institution'), ('howMany', '2')]
# [('legalForm', 'http://www.wikidata.org/entity/Q2296849'), ('name', 'Societate pe Acțiuni'), ('howMany', '2')]
# [('legalForm', 'http://www.wikidata.org/entity/Q61052628'), ('name', 'Sociedade Anônima'), ('howMany', '2')]
# [('legalForm', 'http://www.wikidata.org/entity/Q43067961'), ('name', 'employee-owned company'), ('howMany', '2')]
# [('legalForm', 'http://www.wikidata.org/entity/Q5466628'), ('name', 'for-profit corporation'), ('howMany', '2')]
# [('legalForm', 'http://www.wikidata.org/entity/Q108678744'), ('name', 'joint limited liability company'), ('howMany', '2')]
# [('legalForm', 'http://www.wikidata.org/entity/Q15177651'), ('name', 'Swiss association'), ('howMany', '2')]
# [('legalForm', 'http://www.wikidata.org/entity/Q26839244'), ('name', 'A.E.'), ('howMany', '2')]
# [('legalForm', 'http://www.wikidata.org/entity/Q40734470'), ('name', 'Public Interest Incorporated Foundation'), ('howMany', '2')]
# [('legalForm', 'http://www.wikidata.org/entity/Q3885688'), ('name', 'ONLUS'), ('howMany', '2')]
# [('legalForm', 'http://www.wikidata.org/entity/Q1630714'), ('name', 'general partnership'), ('howMany', '2')]
# [('legalForm', 'http://www.wikidata.org/entity/Q192283'), ('name', 'news agency'), ('howMany', '2')]
# [('legalForm', 'http://www.wikidata.org/entity/Q3487908'), ('name', 'venture capital firm'), ('howMany', '2')]
# [('legalForm', 'http://www.wikidata.org/entity/Q4056382'), ('name', 'autonomous non-commercial organization'), ('howMany', '2')]
# [('legalForm', 'http://www.wikidata.org/entity/Q622439'), ('name', 'small and medium enterprises'), ('howMany', '2')]
# [('legalForm', 'http://www.wikidata.org/entity/Q1422253'), ('name', 'royal charter'), ('howMany', '2')]
# [('legalForm', 'http://www.wikidata.org/entity/Q2388316'), ('name', 'public'), ('howMany', '2')]
# [('legalForm', 'http://www.wikidata.org/entity/Q2996615'), ('name', 'agricultural cooperative'), ('howMany', '2')]
# [('legalForm', 'http://www.wikidata.org/entity/Q22687'), ('name', 'bank'), ('howMany', '2')]
# [('legalForm', 'http://www.wikidata.org/entity/Q2608849'), ('name', 'imprint'), ('howMany', '2')]
# [('legalForm', 'http://www.wikidata.org/entity/Q59553900'), ('name', 'S.A.U.'), ('howMany', '2')]
# [('legalForm', 'http://www.wikidata.org/entity/Q568338'), ('name', 'limited liability'), ('howMany', '2')]
# [('legalForm', 'http://www.wikidata.org/entity/Q6130986'), ('name', 'S.A.'), ('howMany', '2')]
# [('legalForm', 'http://www.wikidata.org/entity/Q7250430'), ('name', 'proprietary company'), ('howMany', '2')]
# [('legalForm', 'http://www.wikidata.org/entity/Q16985745'), ('name', 'transportation network company'), ('howMany', '2')]
# [('legalForm', 'http://www.wikidata.org/entity/Q4906718'), ('name', 'Big business'), ('howMany', '2')]
# [('legalForm', 'http://www.wikidata.org/entity/Q750656'), ('name', 'hypermarket'), ('howMany', '2')]
# [('legalForm', 'http://www.wikidata.org/entity/Q28124941'), ('name', 'foundation of public utility'), ('howMany', '2')]
# [('legalForm', 'http://www.wikidata.org/entity/Q11396960'), ('name', 'production company'), ('howMany', '2')]
# [('legalForm', 'http://www.wikidata.org/entity/Q64699565'), ('name', 'società anonima'), ('howMany', '2')]
# [('legalForm', 'http://www.wikidata.org/entity/Q3118017'), ('name', "groupement d'intérêt économique"), ('howMany', '2')]
# [('legalForm', 'http://www.wikidata.org/entity/Q3631468'), ('name', 'azienda speciale'), ('howMany', '2')]
# [('legalForm', 'http://www.wikidata.org/entity/Q40050'), ('name', 'drink'), ('howMany', '2')]
# [('legalForm', 'http://www.wikidata.org/entity/Q17000076'), ('name', 'gōshi gaisha'), ('howMany', '2')]
# [('legalForm', 'http://www.wikidata.org/entity/Q31273043'), ('name', 'non-profit association'), ('howMany', '2')]
# [('legalForm', 'http://www.wikidata.org/entity/Q2800294'), ('name', 'cooperative society'), ('howMany', '2')]
# [('legalForm', 'http://www.wikidata.org/entity/Q25500509'), ('name', 'commercial association'), ('howMany', '2')]
# [('legalForm', 'http://www.wikidata.org/entity/Q296657'), ('name', 'LLC'), ('howMany', '2')]
# [('legalForm', 'http://www.wikidata.org/entity/Q6785141'), ('name', 'master limited partnership'), ('howMany', '2')]
# [('legalForm', 'http://www.wikidata.org/entity/Q4887441'), ('name', 'benefit corporation'), ('howMany', '2')]
# [('legalForm', 'http://www.wikidata.org/entity/Q99691502'), ('name', 'gjensidig forsikringsselskap'), ('howMany', '2')]
# [('legalForm', 'http://www.wikidata.org/entity/Q56585727'), ('name', 'S.A. de C.V.'), ('howMany', '2')]
# [('legalForm', 'http://www.wikidata.org/entity/Q95999820'), ('name', 'sub-entity in the CCR'), ('howMany', '2')]
# [('legalForm', 'http://www.wikidata.org/entity/Q1752459'), ('name', 'investment company'), ('howMany', '2')]
# [('legalForm', 'http://www.wikidata.org/entity/Q56242138'), ('name', 'German foundation under civil law'), ('howMany', '2')]
# [('legalForm', 'http://www.wikidata.org/entity/Q1453508'), ('name', 'cooperative with limited liabilities'), ('howMany', '2')]
# [('legalForm', 'http://www.wikidata.org/entity/Q3248417'), ('name', 'private'), ('howMany', '2')]
# [('legalForm', 'http://www.wikidata.org/entity/Q102337260'), ('name', 'limited liability partnership'), ('howMany', '2')]
# [('legalForm', 'http://www.wikidata.org/entity/Q10426040'), ('name', 'Bankaktiebolag'), ('howMany', '2')]
# [('legalForm', 'http://www.wikidata.org/entity/Q11900271'), ('name', 'valtion liikelaitos'), ('howMany', '1')]
# [('legalForm', 'http://www.wikidata.org/entity/Q3091505'), ('name', 'co-operative federation'), ('howMany', '1')]
# [('legalForm', 'http://www.wikidata.org/entity/Q1780027'), ('name', 'partnership limited by shares'), ('howMany', '1')]
# [('legalForm', 'http://www.wikidata.org/entity/Q11570784'), ('name', 'Tokubetsu Minkan Hōjin'), ('howMany', '1')]
# [('legalForm', 'http://www.wikidata.org/entity/Q69773580'), ('name', 'Emtec Colleges Limited'), ('howMany', '1')]
# [('legalForm', 'http://www.wikidata.org/entity/Q7928543'), ('name', 'Vietnam Posts and Telecommunications Group'), ('howMany', '1')]
# [('legalForm', 'http://www.wikidata.org/entity/Q179412'), ('name', "Fédération Internationale de l'Automobile"), ('howMany', '1')]
# [('legalForm', 'http://www.wikidata.org/entity/Q4107285'), ('name', 'venture business'), ('howMany', '1')]
# [('legalForm', 'http://www.wikidata.org/entity/Q484652'), ('name', 'international organization'), ('howMany', '1')]
# [('legalForm', 'http://www.wikidata.org/entity/Q108098626'), ('name', 'unitary enterprise'), ('howMany', '1')]
# [('legalForm', 'http://www.wikidata.org/entity/Q69787585'), ('name', 'Établissement public (Luxembourg)'), ('howMany', '1')]
# [('legalForm', 'http://www.wikidata.org/entity/Q2485448'), ('name', 'sports governing body'), ('howMany', '1')]
# [('legalForm', 'http://www.wikidata.org/entity/Q1163643'), ('name', 'classification society'), ('howMany', '1')]
# [('legalForm', 'http://www.wikidata.org/entity/Q191360'), ('name', 'foundation'), ('howMany', '1')]
# [('legalForm', 'http://www.wikidata.org/entity/Q61053380'), ('name', 'S.A.I.C.'), ('howMany', '1')]
# [('legalForm', 'http://www.wikidata.org/entity/Q444863'), ('name', 'Altrechtlicher Verein'), ('howMany', '1')]
# [('legalForm', 'http://www.wikidata.org/entity/Q106986774'), ('name', 'mutual insurance company'), ('howMany', '1')]
# [('legalForm', 'http://www.wikidata.org/entity/Q654302'), ('name', 'Group'), ('howMany', '1')]
# [('legalForm', 'http://www.wikidata.org/entity/Q507619'), ('name', 'retail chain'), ('howMany', '1')]
# [('legalForm', 'http://www.wikidata.org/entity/Q108348457'), ('name', 'production republican unitary enterprise'), ('howMany', '1')]
# [('legalForm', 'http://www.wikidata.org/entity/Q765517'), ('name', 'credit rating agency'), ('howMany', '1')]
# [('legalForm', 'http://www.wikidata.org/entity/Q89651395'), ('name', 'Bundesanstalt öffentlichen Rechts'), ('howMany', '1')]
# [('legalForm', 'http://www.wikidata.org/entity/Q98927546'), ('name', 'Washington corporation'), ('howMany', '1')]
# [('legalForm', 'http://www.wikidata.org/entity/Q7275'), ('name', 'state'), ('howMany', '1')]
# [('legalForm', 'http://www.wikidata.org/entity/Q910379'), ('name', 'Leonardo'), ('howMany', '1')]
# [('legalForm', 'http://www.wikidata.org/entity/Q2348860'), ('name', 'Stiftung & Co. KGaA'), ('howMany', '1')]
# [('legalForm', 'http://www.wikidata.org/entity/Q108098811'), ('name', 'foreign limited liability company'), ('howMany', '1')]
# [('legalForm', 'http://www.wikidata.org/entity/Q123733'), ('name', 'hospitality service'), ('howMany', '1')]
# [('legalForm', 'http://www.wikidata.org/entity/Q1102362'), ('name', 'Close Corporation'), ('howMany', '1')]
# [('legalForm', 'http://www.wikidata.org/entity/Q5154974'), ('name', 'community interest company'), ('howMany', '1')]
# [('legalForm', 'http://www.wikidata.org/entity/Q11570934'), ('name', 'specified non-profit corporation'), ('howMany', '1')]
# [('legalForm', 'http://www.wikidata.org/entity/Q55190098'), ('name', 'organisasjonsledd'), ('howMany', '1')]
# [('legalForm', 'http://www.wikidata.org/entity/Q16869121'), ('name', 'proprietor'), ('howMany', '1')]
# [('legalForm', 'http://www.wikidata.org/entity/Q94933'), ('name', 'Take-Two Interactive'), ('howMany', '1')]
# [('legalForm', 'http://www.wikidata.org/entity/Q1045758'), ('name', 'United Technologies Corporation'), ('howMany', '1')]
# [('legalForm', 'http://www.wikidata.org/entity/Q56317876'), ('name', 'Entreprise à mission'), ('howMany', '1')]
# [('legalForm', 'http://www.wikidata.org/entity/Q91418196'), ('name', 'PT tertutup'), ('howMany', '1')]
# [('legalForm', 'http://www.wikidata.org/entity/Q15991739'), ('name', 'Private Enterprise Foundation'), ('howMany', '1')]
# [('legalForm', 'http://www.wikidata.org/entity/Q3488258'), ('name', 'general partnership'), ('howMany', '1')]
# [('legalForm', 'http://www.wikidata.org/entity/Q91417950'), ('name', 'PT terbuka'), ('howMany', '1')]
# [('legalForm', 'http://www.wikidata.org/entity/Q219409'), ('name', 'venture capital'), ('howMany', '1')]
# [('legalForm', 'http://www.wikidata.org/entity/Q221096'), ('name', 'public–private partnership'), ('howMany', '1')]
# [('legalForm', 'http://www.wikidata.org/entity/Q1417728'), ('name', 'trade name'), ('howMany', '1')]
# [('legalForm', 'http://www.wikidata.org/entity/Q107173841'), ('name', 'insurance company'), ('howMany', '1')]
# [('legalForm', 'http://www.wikidata.org/entity/Q484847'), ('name', 'e-commerce'), ('howMany', '1')]
# [('legalForm', 'http://www.wikidata.org/entity/Q5627756'), ('name', 'gōmei gaisha'), ('howMany', '1')]
# [('legalForm', 'http://www.wikidata.org/entity/Q1421490'), ('name', 'government-sponsored enterprise'), ('howMany', '1')]
# [('legalForm', 'http://www.wikidata.org/entity/Q11033'), ('name', 'mass media'), ('howMany', '1')]
# [('legalForm', 'http://www.wikidata.org/entity/Q3376073'), ('name', 'corporate personhood'), ('howMany', '1')]
# [('legalForm', 'http://www.wikidata.org/entity/Q19391573'), ('name', 'annet foretak ifølge særskilt lov'), ('howMany', '1')]
# [('legalForm', 'http://www.wikidata.org/entity/Q56410106'), ('name', 'Limited stock company'), ('howMany', '1')]
# [('legalForm', 'http://www.wikidata.org/entity/Q78443472'), ('name', 'public-benefit corporation'), ('howMany', '1')]
# [('legalForm', 'http://www.wikidata.org/entity/Q248'), ('name', 'Intel'), ('howMany', '1')]
# [('legalForm', 'http://www.wikidata.org/entity/Q69496549'), ('name', 'società in nome collettivo'), ('howMany', '1')]
# [('legalForm', 'http://www.wikidata.org/entity/Q5328616'), ('name', 'partial cooperative'), ('howMany', '1')]
# [('legalForm', 'http://www.wikidata.org/entity/Q108098624'), ('name', 'republican unitary enterprise'), ('howMany', '1')]
# [('legalForm', 'http://www.wikidata.org/entity/Q56879301'), ('name', 'Ltda.'), ('howMany', '1')]
# [('legalForm', 'http://www.wikidata.org/entity/Q567521'), ('name', 'commercial company'), ('howMany', '1')]
# [('legalForm', 'http://www.wikidata.org/entity/Q158668'), ('name', 'private'), ('howMany', '1')]
# [('legalForm', 'http://www.wikidata.org/entity/Q31855'), ('name', 'research institute'), ('howMany', '1')]
# [('legalForm', 'http://www.wikidata.org/entity/Q1746408'), ('name', 'Kleine Aktiengesellschaft'), ('howMany', '1')]
# [('legalForm', 'http://www.wikidata.org/entity/Q2324835'), ('name', 'national railway'), ('howMany', '1')]
# [('legalForm', 'http://www.wikidata.org/entity/Q294163'), ('name', 'public institution'), ('howMany', '1')]
# [('legalForm', 'http://www.wikidata.org/entity/Q1061635'), ('name', 'video game development'), ('howMany', '1')]
# [('legalForm', 'http://www.wikidata.org/entity/Q131207'), ('name', 'cosmetics'), ('howMany', '1')]
# [('legalForm', 'http://www.wikidata.org/entity/Q11863217'), ('name', 'Czech public research institution'), ('howMany', '1')]
# [('legalForm', 'http://www.wikidata.org/entity/Q1295201'), ('name', 'grocery store'), ('howMany', '1')]
# [('legalForm', 'http://www.wikidata.org/entity/Q2297457'), ('name', 'junior enterprise'), ('howMany', '1')]
# [('legalForm', 'http://www.wikidata.org/entity/Q17108073'), ('name', 'Scopely'), ('howMany', '1')]
# [('legalForm', 'http://www.wikidata.org/entity/Q483242'), ('name', 'laboratory'), ('howMany', '1')]
# [('legalForm', 'http://www.wikidata.org/entity/Q67583337'), ('name', 'účastnický fond'), ('howMany', '1')]
# [('legalForm', 'http://www.wikidata.org/entity/Q485016'), ('name', 'kolkhoz'), ('howMany', '1')]
# [('legalForm', 'http://www.wikidata.org/entity/Q162157'), ('name', 'chartered company'), ('howMany', '1')]
# [('legalForm', 'http://www.wikidata.org/entity/Q7383772'), ('name', 'registered association'), ('howMany', '1')]
# [('legalForm', 'http://www.wikidata.org/entity/Q6566978'), ('name', 'central enterprise'), ('howMany', '1')]
# [('legalForm', 'http://www.wikidata.org/entity/Q702627'), ('name', 'public property'), ('howMany', '1')]
# [('legalForm', 'http://www.wikidata.org/entity/Q232846'), ('name', 'branch'), ('howMany', '1')]
# [('legalForm', 'http://www.wikidata.org/entity/Q11391964'), ('name', 'Kōdan'), ('howMany', '1')]
# [('legalForm', 'http://www.wikidata.org/entity/Q854022'), ('name', 'trust'), ('howMany', '1')]
# [('legalForm', 'http://www.wikidata.org/entity/Q4498092'), ('name', 'mechanized bakery'), ('howMany', '1')]
# [('legalForm', 'http://www.wikidata.org/entity/Q7552937'), ('name', 'Société anonyme libanaise'), ('howMany', '1')]
# [('legalForm', 'http://www.wikidata.org/entity/Q61056688'), ('name', 'Industrial Enterprise Owned by the Whole People'), ('howMany', '1')]
# [('legalForm', 'http://www.wikidata.org/entity/Q89654205'), ('name', 'Anstalt des öffentlichen Rechts'), ('howMany', '1')]
# [('legalForm', 'http://www.wikidata.org/entity/Q2901333'), ('name', 'S corporation'), ('howMany', '1')]
# [('legalForm', 'http://www.wikidata.org/entity/Q10879990'), ('name', 'public institution'), ('howMany', '1')]
# [('legalForm', 'http://www.wikidata.org/entity/Q108494513'), ('name', 'società consortile a responsabilità limitata'), ('howMany', '1')]
# [('legalForm', 'http://www.wikidata.org/entity/Q12377470'), ('name', 'general partnership'), ('howMany', '1')]
# [('legalForm', 'http://www.wikidata.org/entity/Q823196'), ('name', 'Winemaking cooperative'), ('howMany', '1')]
# [('legalForm', 'http://www.wikidata.org/entity/Q5015128'), ('name', 'C corporation'), ('howMany', '1')]
# [('legalForm', 'http://www.wikidata.org/entity/Q108103696'), ('name', 'New York Business Corporation'), ('howMany', '1')]
# [('legalForm', 'http://www.wikidata.org/entity/Q6130988'), ('name', 'S.A.B'), ('howMany', '1')]
# [('legalForm', 'http://www.wikidata.org/entity/Q16726184'), ('name', 'Sociedad de responsabilidad limitada'), ('howMany', '1')]
# [('legalForm', 'http://www.wikidata.org/entity/Q1521034'), ('name', 'partnership'), ('howMany', '1')]
# [('legalForm', 'http://www.wikidata.org/entity/Q971946'), ('name', 'KDDI'), ('howMany', '1')]
# [('legalForm', 'http://www.wikidata.org/entity/Q7616418'), ('name', 'stiftelse'), ('howMany', '1')]
# [('legalForm', 'http://www.wikidata.org/entity/Q60198861'), ('name', 'foundation recognized of public utility in France'), ('howMany', '1')]
# [('legalForm', 'http://www.wikidata.org/entity/Q56344968'), ('name', 'incorporated foundation'), ('howMany', '1')]
# [('legalForm', 'http://www.wikidata.org/entity/Q4484758'), ('name', 'Financial Industrial Group'), ('howMany', '1')]
# [('legalForm', 'http://www.wikidata.org/entity/Q11873437'), ('name', 'kunnallinen liikelaitos'), ('howMany', '1')]
# [('legalForm', 'http://www.wikidata.org/entity/Q155076'), ('name', 'juridical person'), ('howMany', '1')]
# [('legalForm', 'http://www.wikidata.org/entity/Q2865305'), ('name', 'trading company'), ('howMany', '1')]
# [('legalForm', 'http://www.wikidata.org/entity/Q1846372'), ('name', 'Federal Public Service'), ('howMany', '1')]
# [('legalForm', 'http://www.wikidata.org/entity/Q161500'), ('name', 'privatization'), ('howMany', '1')]
# [('legalForm', 'http://www.wikidata.org/entity/Q7257704'), ('name', 'public benefit organization'), ('howMany', '1')]
# [('legalForm', 'http://www.wikidata.org/entity/Q1939471'), ('name', 'worker cooperative'), ('howMany', '1')]
# [('legalForm', 'http://www.wikidata.org/entity/Q6428384'), ('name', 'kommandittselskap'), ('howMany', '1')]
# [('legalForm', 'http://www.wikidata.org/entity/Q1880737'), ('name', 'branch office'), ('howMany', '1')]
# [('legalForm', 'http://www.wikidata.org/entity/Q16561879'), ('name', 'Empresa del Estado'), ('howMany', '1')]
# [('legalForm', 'http://www.wikidata.org/entity/Q63439515'), ('name', 'Berhad'), ('howMany', '1')]
# [('legalForm', 'http://www.wikidata.org/entity/Q5354754'), ('name', 'talent agency'), ('howMany', '1')]
# [('legalForm', 'http://www.wikidata.org/entity/Q98695000'), ('name', 'Sociedad de responsabilidad limitada'), ('howMany', '1')]
# [('legalForm', 'http://www.wikidata.org/entity/Q171947'), ('name', 'franchising'), ('howMany', '1')]
# [('legalForm', 'http://www.wikidata.org/entity/Q10610815'), ('name', 'Opinbert hlutafélag'), ('howMany', '1')]
# [('legalForm', 'http://www.wikidata.org/entity/Q2143354'), ('name', 'insurance company'), ('howMany', '1')]
# [('legalForm', 'http://www.wikidata.org/entity/Q3487951'), ('name', 'Société de groupe d’assurance mutuelle'), ('howMany', '1')]
# [('legalForm', 'http://www.wikidata.org/entity/Q56194030'), ('name', 'Section 8 Company'), ('howMany', '1')]
# [('legalForm', 'http://www.wikidata.org/entity/Q54814599'), ('name', 'general foundation'), ('howMany', '1')]
# [('legalForm', 'http://www.wikidata.org/entity/Q145'), ('name', 'United Kingdom'), ('howMany', '1')]
# [('legalForm', 'http://www.wikidata.org/entity/Q98834261'), ('name', 'limited liability company'), ('howMany', '1')]
# [('legalForm', 'http://www.wikidata.org/entity/Q467970'), ('name', 'permanent establishment'), ('howMany', '1')]
# [('legalForm', 'http://www.wikidata.org/entity/Q17376040'), ('name', 'société à responsabilité limitée'), ('howMany', '1')]
# [('legalForm', 'http://www.wikidata.org/entity/Q483946'), ('name', 'POSCO'), ('howMany', '1')]
# [('legalForm', 'http://www.wikidata.org/entity/Q11637920'), ('name', "Agricultural Producers' Co-operative Corporation"), ('howMany', '1')]
# [('legalForm', 'http://www.wikidata.org/entity/Q327333'), ('name', 'government agency'), ('howMany', '1')]
# [('legalForm', 'http://www.wikidata.org/entity/Q11781066'), ('name', 'microregion'), ('howMany', '1')]
# [('legalForm', 'http://www.wikidata.org/entity/Q988108'), ('name', 'club'), ('howMany', '1')]
# [('legalForm', 'http://www.wikidata.org/entity/Q53361238'), ('name', 'association'), ('howMany', '1')]
# [('legalForm', 'http://www.wikidata.org/entity/Q240625'), ('name', '501(c) organization'), ('howMany', '1')]
# [('legalForm', 'http://www.wikidata.org/entity/Q7045238'), ('name', 'no-liability company'), ('howMany', '1')]
# [('legalForm', 'http://www.wikidata.org/entity/Q61472992'), ('name', 'A.E.E.X.'), ('howMany', '1')]
# [('legalForm', 'http://www.wikidata.org/entity/Q99528763'), ('name', 'other legal person'), ('howMany', '1')]
# [('legalForm', 'http://www.wikidata.org/entity/Q98702364'), ('name', 'B.V. & Co. KG'), ('howMany', '1')]
# [('legalForm', 'http://www.wikidata.org/entity/Q100152139'), ('name', 'Public limited insurance company'), ('howMany', '1')]
# [('legalForm', 'http://www.wikidata.org/entity/Q27629635'), ('name', 'eenmanszaak'), ('howMany', '1')]
# 436

# %%
#let's restrict to our 3 target countries
q = f"""
select ?legalForm ?name (count(*) as ?howMany) where{{
# ?company wdt:P31 wd:Q4830453 ;
    wdt:P1454 ?legalForm ;
    wdt:P17 ?country .
# ?legalForm <http://schema.org/name> ?name .
filter(?country in (wd:Q16, wd:Q145, wd:Q30))
}}
group by ?name ?legalForm
order by desc (?howMany)
"""
run_query(q)
# Out:
# [('legalForm', 'http://www.wikidata.org/entity/Q891723'), ('name', 'public company'), ('howMany', '492')]
# [('legalForm', 'http://www.wikidata.org/entity/Q134161'), ('name', 'joint-stock company'), ('howMany', '395')]
# [('legalForm', 'http://www.wikidata.org/entity/Q1589009'), ('name', 'privately held company'), ('howMany', '343')]
# [('legalForm', 'http://www.wikidata.org/entity/Q5225895'), ('name', 'public limited company'), ('howMany', '256')]
# [('legalForm', 'http://www.wikidata.org/entity/Q6832945'), ('name', 'private company limited by shares'), ('howMany', '231')]
# [('legalForm', 'http://www.wikidata.org/entity/Q149789'), ('name', 'limited liability company'), ('howMany', '198')]
# [('legalForm', 'http://www.wikidata.org/entity/Q783794'), ('name', 'company'), ('howMany', '92')]
# [('legalForm', 'http://www.wikidata.org/entity/Q658255'), ('name', 'subsidiary'), ('howMany', '86')]
# [('legalForm', 'http://www.wikidata.org/entity/Q167037'), ('name', 'corporation'), ('howMany', '79')]
# [('legalForm', 'http://www.wikidata.org/entity/Q422074'), ('name', 'corporation'), ('howMany', '77')]
# [('legalForm', 'http://www.wikidata.org/entity/Q57655560'), ('name', 'U.S. corporation'), ('howMany', '76')]
# [('legalForm', 'http://www.wikidata.org/entity/Q166280'), ('name', 'S.A.'), ('howMany', '63')]
# [('legalForm', 'http://www.wikidata.org/entity/Q33685'), ('name', 'limited company'), ('howMany', '59')]
# [('legalForm', 'http://www.wikidata.org/entity/Q18624259'), ('name', 'private limited liability company'), ('howMany', '59')]
# [('legalForm', 'http://www.wikidata.org/entity/Q88537331'), ('name', 'Delaware corporation'), ('howMany', '41')]
# [('legalForm', 'http://www.wikidata.org/entity/Q1588658'), ('name', 'limited liability partnership'), ('howMany', '32')]
# [('legalForm', 'http://www.wikidata.org/entity/Q15648878'), ('name', 'S.r.l.'), ('howMany', '23')]
# [('legalForm', 'http://www.wikidata.org/entity/Q909695'), ('name', 'limited partnership'), ('howMany', '19')]
# [('legalForm', 'http://www.wikidata.org/entity/Q105162507'), ('name', 'Registered Society'), ('howMany', '13')]
# [('legalForm', 'http://www.wikidata.org/entity/Q460178'), ('name', 'GmbH'), ('howMany', '12')]
# [('legalForm', 'http://www.wikidata.org/entity/Q5189488'), ('name', 'Crown corporation of Canada'), ('howMany', '11')]
# [('legalForm', 'http://www.wikidata.org/entity/Q693737'), ('name', 'Aktiengesellschaft'), ('howMany', '10')]
# [('legalForm', 'http://www.wikidata.org/entity/Q489209'), ('name', 'joint venture'), ('howMany', '8')]
# [('legalForm', 'http://www.wikidata.org/entity/Q654502'), ('name', 'Société par actions simplifiée'), ('howMany', '8')]
# [('legalForm', 'http://www.wikidata.org/entity/Q4539'), ('name', 'cooperative'), ('howMany', '7')]
# [('legalForm', 'http://www.wikidata.org/entity/Q897103'), ('name', 'GmbH & Co. KG'), ('howMany', '7')]
# [('legalForm', 'http://www.wikidata.org/entity/Q3178478'), ('name', 'incorporation'), ('howMany', '7')]
# [('legalForm', 'http://www.wikidata.org/entity/Q163740'), ('name', 'nonprofit organization'), ('howMany', '7')]
# [('legalForm', 'http://www.wikidata.org/entity/Q955214'), ('name', 'mutual organization'), ('howMany', '6')]
# [('legalForm', 'http://www.wikidata.org/entity/Q1480166'), ('name', 'kabushiki gaisha'), ('howMany', '6')]
# [('legalForm', 'http://www.wikidata.org/entity/Q422062'), ('name', 'Aktiengesellschaft'), ('howMany', '5')]
# [('legalForm', 'http://www.wikidata.org/entity/Q1436139'), ('name', 'Naamloze vennootschap'), ('howMany', '5')]
# [('legalForm', 'http://www.wikidata.org/entity/Q5621421'), ('name', 'private company'), ('howMany', '4')]
# [('legalForm', 'http://www.wikidata.org/entity/Q20180983'), ('name', 'Kompanie'), ('howMany', '4')]
# [('legalForm', 'http://www.wikidata.org/entity/Q15648901'), ('name', 'S.L.'), ('howMany', '4')]
# [('legalForm', 'http://www.wikidata.org/entity/Q4830453'), ('name', 'business'), ('howMany', '3')]
# [('legalForm', 'http://www.wikidata.org/entity/Q19252952'), ('name', 'associated company'), ('howMany', '3')]
# [('legalForm', 'http://www.wikidata.org/entity/Q17084016'), ('name', 'nonprofit corporation'), ('howMany', '3')]
# [('legalForm', 'http://www.wikidata.org/entity/Q422007'), ('name', 'aktiebolag'), ('howMany', '3')]
# [('legalForm', 'http://www.wikidata.org/entity/Q695318'), ('name', 'mutual insurance'), ('howMany', '3')]
# [('legalForm', 'http://www.wikidata.org/entity/Q699386'), ('name', 'statutory corporation'), ('howMany', '3')]
# [('legalForm', 'http://www.wikidata.org/entity/Q422069'), ('name', 'Limited Company'), ('howMany', '3')]
# [('legalForm', 'http://www.wikidata.org/entity/Q646164'), ('name', 'general partnership'), ('howMany', '3')]
# [('legalForm', 'http://www.wikidata.org/entity/Q21980538'), ('name', 'commercial organization'), ('howMany', '3')]
# [('legalForm', 'http://www.wikidata.org/entity/Q15829892'), ('name', 'Gesellschaft mit beschränkter Haftung'), ('howMany', '3')]
# [('legalForm', 'http://www.wikidata.org/entity/Q13641190'), ('name', 'open joint-stock company'), ('howMany', '3')]
# [('legalForm', 'http://www.wikidata.org/entity/Q18325436'), ('name', '501(c)(3) organization'), ('howMany', '3')]
# [('legalForm', 'http://www.wikidata.org/entity/Q4086495'), ('name', 'startup accelerator'), ('howMany', '2')]
# [('legalForm', 'http://www.wikidata.org/entity/Q6881511'), ('name', 'enterprise'), ('howMany', '2')]
# [('legalForm', 'http://www.wikidata.org/entity/Q219577'), ('name', 'holding company'), ('howMany', '2')]
# [('legalForm', 'http://www.wikidata.org/entity/Q334453'), ('name', 'division'), ('howMany', '2')]
# [('legalForm', 'http://www.wikidata.org/entity/Q1518730'), ('name', 'corporate law in the United States'), ('howMany', '2')]
# [('legalForm', 'http://www.wikidata.org/entity/Q18195767'), ('name', 'société anonyme'), ('howMany', '2')]
# [('legalForm', 'http://www.wikidata.org/entity/Q2178147'), ('name', 'trade association'), ('howMany', '2')]
# [('legalForm', 'http://www.wikidata.org/entity/Q1132207'), ('name', 'business incubator'), ('howMany', '2')]
# [('legalForm', 'http://www.wikidata.org/entity/Q422053'), ('name', 'NV/SA'), ('howMany', '2')]
# [('legalForm', 'http://www.wikidata.org/entity/Q728646'), ('name', 'partnership'), ('howMany', '2')]
# [('legalForm', 'http://www.wikidata.org/entity/Q6516200'), ('name', 'private company limited by guarantee'), ('howMany', '2')]
# [('legalForm', 'http://www.wikidata.org/entity/Q697852'), ('name', 'real estate investment trust'), ('howMany', '2')]
# [('legalForm', 'http://www.wikidata.org/entity/Q4887441'), ('name', 'benefit corporation'), ('howMany', '2')]
# [('legalForm', 'http://www.wikidata.org/entity/Q837619'), ('name', 'Kommanditgesellschaft auf Aktien'), ('howMany', '2')]
# [('legalForm', 'http://www.wikidata.org/entity/Q708676'), ('name', 'charitable organization'), ('howMany', '2')]
# [('legalForm', 'http://www.wikidata.org/entity/Q270791'), ('name', 'state-owned enterprise'), ('howMany', '2')]
# [('legalForm', 'http://www.wikidata.org/entity/Q102337260'), ('name', 'limited liability partnership'), ('howMany', '2')]
# [('legalForm', 'http://www.wikidata.org/entity/Q79913'), ('name', 'non-governmental organization'), ('howMany', '1')]
# [('legalForm', 'http://www.wikidata.org/entity/Q69773580'), ('name', 'Emtec Colleges Limited'), ('howMany', '1')]
# [('legalForm', 'http://www.wikidata.org/entity/Q43067961'), ('name', 'employee-owned company'), ('howMany', '1')]
# [('legalForm', 'http://www.wikidata.org/entity/Q5466628'), ('name', 'for-profit corporation'), ('howMany', '1')]
# [('legalForm', 'http://www.wikidata.org/entity/Q4107285'), ('name', 'venture business'), ('howMany', '1')]
# [('legalForm', 'http://www.wikidata.org/entity/Q129238'), ('name', 'startup company'), ('howMany', '1')]
# [('legalForm', 'http://www.wikidata.org/entity/Q15646299'), ('name', 'společnost s ručením omezeným'), ('howMany', '1')]
# [('legalForm', 'http://www.wikidata.org/entity/Q15177651'), ('name', 'Swiss association'), ('howMany', '1')]
# [('legalForm', 'http://www.wikidata.org/entity/Q1163643'), ('name', 'classification society'), ('howMany', '1')]
# [('legalForm', 'http://www.wikidata.org/entity/Q3742388'), ('name', 'società per azioni'), ('howMany', '1')]
# [('legalForm', 'http://www.wikidata.org/entity/Q3885688'), ('name', 'ONLUS'), ('howMany', '1')]
# [('legalForm', 'http://www.wikidata.org/entity/Q98927546'), ('name', 'Washington corporation'), ('howMany', '1')]
# [('legalForm', 'http://www.wikidata.org/entity/Q3055265'), ('name', 'single member limited liability company'), ('howMany', '1')]
# [('legalForm', 'http://www.wikidata.org/entity/Q161726'), ('name', 'multinational corporation'), ('howMany', '1')]
# [('legalForm', 'http://www.wikidata.org/entity/Q123733'), ('name', 'hospitality service'), ('howMany', '1')]
# [('legalForm', 'http://www.wikidata.org/entity/Q2624520'), ('name', 'aktieselskab'), ('howMany', '1')]
# [('legalForm', 'http://www.wikidata.org/entity/Q1102362'), ('name', 'Close Corporation'), ('howMany', '1')]
# [('legalForm', 'http://www.wikidata.org/entity/Q5154974'), ('name', 'community interest company'), ('howMany', '1')]
# [('legalForm', 'http://www.wikidata.org/entity/Q94933'), ('name', 'Take-Two Interactive'), ('howMany', '1')]
# [('legalForm', 'http://www.wikidata.org/entity/Q1045758'), ('name', 'United Technologies Corporation'), ('howMany', '1')]
# [('legalForm', 'http://www.wikidata.org/entity/Q1422253'), ('name', 'royal charter'), ('howMany', '1')]
# [('legalForm', 'http://www.wikidata.org/entity/Q15991739'), ('name', 'Private Enterprise Foundation'), ('howMany', '1')]
# [('legalForm', 'http://www.wikidata.org/entity/Q2912172'), ('name', 'sole proprietorship'), ('howMany', '1')]
# [('legalForm', 'http://www.wikidata.org/entity/Q2388316'), ('name', 'public'), ('howMany', '1')]
# [('legalForm', 'http://www.wikidata.org/entity/Q1421490'), ('name', 'government-sponsored enterprise'), ('howMany', '1')]
# [('legalForm', 'http://www.wikidata.org/entity/Q56489561'), ('name', 'sociedad anónima'), ('howMany', '1')]
# [('legalForm', 'http://www.wikidata.org/entity/Q78443472'), ('name', 'public-benefit corporation'), ('howMany', '1')]
# [('legalForm', 'http://www.wikidata.org/entity/Q333920'), ('name', 'Oy'), ('howMany', '1')]
# [('legalForm', 'http://www.wikidata.org/entity/Q1061635'), ('name', 'video game development'), ('howMany', '1')]
# [('legalForm', 'http://www.wikidata.org/entity/Q17375963'), ('name', 'Besloten vennootschap'), ('howMany', '1')]
# [('legalForm', 'http://www.wikidata.org/entity/Q157031'), ('name', 'foundation'), ('howMany', '1')]
# [('legalForm', 'http://www.wikidata.org/entity/Q11396960'), ('name', 'production company'), ('howMany', '1')]
# [('legalForm', 'http://www.wikidata.org/entity/Q2901333'), ('name', 'S corporation'), ('howMany', '1')]
# [('legalForm', 'http://www.wikidata.org/entity/Q778575'), ('name', 'conglomerate'), ('howMany', '1')]
# [('legalForm', 'http://www.wikidata.org/entity/Q108103696'), ('name', 'New York Business Corporation'), ('howMany', '1')]
# [('legalForm', 'http://www.wikidata.org/entity/Q296657'), ('name', 'LLC'), ('howMany', '1')]
# [('legalForm', 'http://www.wikidata.org/entity/Q6785141'), ('name', 'master limited partnership'), ('howMany', '1')]
# [('legalForm', 'http://www.wikidata.org/entity/Q5015128'), ('name', 'C corporation'), ('howMany', '1')]
# [('legalForm', 'http://www.wikidata.org/entity/Q48204'), ('name', 'voluntary organization'), ('howMany', '1')]
# [('legalForm', 'http://www.wikidata.org/entity/Q145'), ('name', 'United Kingdom'), ('howMany', '1')]
# [('legalForm', 'http://www.wikidata.org/entity/Q1752459'), ('name', 'investment company'), ('howMany', '1')]
# [('legalForm', 'http://www.wikidata.org/entity/Q10379632'), ('name', 'Société à responsabilité limitée'), ('howMany', '1')]
# [('legalForm', 'http://www.wikidata.org/entity/Q240625'), ('name', '501(c) organization'), ('howMany', '1')]
# [('legalForm', 'http://www.wikidata.org/entity/Q165758'), ('name', 'Kommanditgesellschaft'), ('howMany', '1')]
# [('legalForm', 'http://www.wikidata.org/entity/Q375336'), ('name', 'film studio'), ('howMany', '1')]
# [('legalForm', 'http://www.wikidata.org/entity/Q49168310'), ('name', 'Société Anonyme'), ('howMany', '1')]
# 110

# %%
#can a company have more than 1 legal form?
q = f"""
select ?companyName (count(?legalForm) as ?count) where{{
# ?company wdt:P31 wd:Q4830453 ;
    wdt:P1454 ?legalForm ;
    <http://schema.org/name> ?companyName .
}}
group by ?companyName
order by desc(?count)
limit 10
"""
run_query(q)
# Out:
# [('companyName', 'Norma'), ('count', '4')]
# [('companyName', 'Honeywell'), ('count', '3')]
# [('companyName', 'Banque Saudi Fransi'), ('count', '3')]
# [('companyName', 'China Unicom'), ('count', '3')]
# [('companyName', 'Aston Martin Lagonda'), ('count', '3')]
# [('companyName', 'Siemens'), ('count', '3')]
# [('companyName', 'Zenit'), ('count', '3')]
# [('companyName', 'ELBA'), ('count', '3')]
# [('companyName', 'Nintendo Australia'), ('count', '3')]
# [('companyName', 'Mobileye'), ('count', '3')]
# 10

# %% [markdown]
# ## Copy of goals to avoid scrolling
#
# 5. Analyze the number of employees  and other relevant numeric attributes
#     5.1 What are the top-10 companies for a given attribute?
#     5.2 For which companies is defined some form of income or market capitalization or total assets? What is the min, max, and average in each category and country?
#     5.3 Which business in each country owns more businesses in other countries?

# %%
#let's answer 5.1
#top-10 for number of employees between US UK and Canada
q = f"""
select ?name ?employees where{{
# ?company wdt:P31 wd:Q4830453 ;
    wdt:P1128 ?employees ;
    wdt:P17 ?country ;
    <http://schema.org/name> ?name .
filter(?country in (wd:Q16, wd:Q30, wd:Q145))
}}
order by desc(?employees)
limit(10)
"""
run_query(q)
# Out:
# [('name', 'Walmart'), ('employees', '2500000')]
# [('name', 'Amazon'), ('employees', '1298000')]
# [('name', 'G4S'), ('employees', '618260')]
# [('name', 'United Parcel Service'), ('employees', '434000')]
# [('name', 'Tesco'), ('employees', '423092')]
# [('name', 'Yum China'), ('employees', '420000')]
# [('name', 'R. J. Reynolds Tobacco Company'), ('employees', '400000')]
# [('name', 'FedEx'), ('employees', '400000')]
# [('name', 'The Home Depot'), ('employees', '400000')]
# [('name', 'Berkshire Hathaway'), ('employees', '360000')]
# 10

# %%
#let's add the country as well
q = f"""
select ?name ?employees ?countryName where{{
# ?company wdt:P31 wd:Q4830453 ;
    wdt:P1128 ?employees ;
    wdt:P17 ?country ;
    <http://schema.org/name> ?name .
# ?country <http://schema.org/name> ?countryName .
filter(?country in (wd:Q16, wd:Q30, wd:Q145))
}}
order by desc(?employees)
limit(10)
"""
run_query(q)
# Out:
# [('name', 'Walmart'), ('employees', '2500000'), ('countryName', 'United States of America')]
# [('name', 'Amazon'), ('employees', '1298000'), ('countryName', 'United States of America')]
# [('name', 'G4S'), ('employees', '618260'), ('countryName', 'United Kingdom')]
# [('name', 'United Parcel Service'), ('employees', '434000'), ('countryName', 'United States of America')]
# [('name', 'Tesco'), ('employees', '423092'), ('countryName', 'United Kingdom')]
# [('name', 'Yum China'), ('employees', '420000'), ('countryName', 'United States of America')]
# [('name', 'R. J. Reynolds Tobacco Company'), ('employees', '400000'), ('countryName', 'United States of America')]
# [('name', 'FedEx'), ('employees', '400000'), ('countryName', 'United States of America')]
# [('name', 'The Home Depot'), ('employees', '400000'), ('countryName', 'United States of America')]
# [('name', 'Berkshire Hathaway'), ('employees', '360000'), ('countryName', 'United States of America')]
# 10

# %% [markdown]
# ## Copy of goals to avoid scrolling
#
# 5. Analyze the number of employees  and other relevant numeric attributes
#     ~~5.1 What are the top-10 companies for a given attribute?~~
#     5.2 For which companies is defined some form of income or market capitalization or total assets? What is the min, max, and average in each category and country?
#     5.3 Which business in each country owns more businesses in other countries?

# %%
#to answer goal 5.2 i need more properties
#i could search again those properties among the names i found earlier, let's try and use regex instead this time
q = f"""
select distinct ?property ?name where{{
# ?company wdt:P31 wd:Q4830453 .
# ?company ?property ?object .
# ?property <http://schema.org/name> ?name .
filter regex(?name, '.*(assets|income|market).*') .
}}
"""
run_query(q)
# Out:
# [('property', 'http://www.wikidata.org/prop/direct/P2403'), ('name', 'total assets')]
# [('property', 'http://www.wikidata.org/prop/direct/P3362'), ('name', 'operating income')]
# [('property', 'http://www.wikidata.org/prop/direct/P7534'), ('name', 'MIC market code')]
# [('property', 'http://www.wikidata.org/prop/direct/P3679'), ('name', 'stock market index')]
# [('property', 'http://www.wikidata.org/prop/direct/P2226'), ('name', 'market capitalization')]
# [('property', 'http://www.wikidata.org/prop/direct/P4103'), ('name', 'assets under management')]
# [('property', 'http://www.wikidata.org/prop/direct/P2770'), ('name', 'source of income')]
# 7

# %%
#the properties i need are then
total_assets = 'wdt:P2403'
market_capit = 'wdt:P2226'
op_income = 'wdt:P3362'

#the first part of 5.2 suggests that maybe not all companies have all of the 3 properties, let's try and count those that have that properties
#count first total number of companies
q = f"""
select (count(*) as ?n_companies) where{{
# ?company wdt:P31 wd:Q4830453
}}
"""
run_query(q)
# Out:
# [('n_companies', '193935')]
# 1

# %%
#let's count now all the companies that have at least one of those properties

#first select each company one time
q = f"""
select distinct ?company where{{
# ?company wdt:P31 wd:Q4830453 ;
    wdt:P2403 | wdt:P2226 | wdt:P3362 ?value .
}}
"""
#count all the companies
q2 = f"""
select (count(*) as ?tot) where{{
    {{
        select distinct ?company where{{

# ?company wdt:P31 wd:Q4830453 ;

    wdt:P2403 | wdt:P2226 | wdt:P3362 ?value .

}}



    }}
}}
"""
run_query(q2)
# Out:
# [('tot', '1516')]
# 1

# %% [markdown]
# ## Copy of goals to avoid scrolling
#
# 5. Analyze the number of employees  and other relevant numeric attributes
#     ~~5.1 What are the top-10 companies for a given attribute?~~
#     5.2 For which companies is defined some form of income or market capitalization or total assets? What is the min, max, and average in each category and country?
#     5.3 Which business in each country owns more businesses in other countries?

# %%
#5.2) to answer to "What is the min, max, and average in each category and country?" we run 3 separate queries
#for each of those 3

#income
#market capitalization
#total assets

#min max and average of total income for each country
q = f"""
select ?name (avg(?v) as ?avg) (min(?v) as ?min) (max(?v) as ?max) where{{
# ?country <http://schema.org/name> ?name .
    {{
        select ?country ?v where{{
            # ?company wdt:P31 wd:Q4830453 .
            # ?company wdt:P3362 ?v .
            # ?company wdt:P17 ?country .
        }}
    }}

}}
group by ?name
order by asc (?name)
"""
print("Income")
run_query(q)
# Out:
# Income
# [('name', 'Argentina'), ('avg', '2180424362.333333333333333'), ('min', '-8920000'), ('max', '6549300000')]
# [('name', 'Australia'), ('avg', '15996000000'), ('min', '15996000000'), ('max', '15996000000')]
# [('name', 'Austria'), ('avg', '63277500'), ('min', '-457000000'), ('max', '424910000')]
# [('name', 'Austria-Hungary'), ('avg', '-1637000'), ('min', '-1637000'), ('max', '-1637000')]
# [('name', 'Austrian Empire'), ('avg', '-1637000'), ('min', '-1637000'), ('max', '-1637000')]
# [('name', 'Belarus'), ('avg', '165383250'), ('min', '761000'), ('max', '486577000')]
# [('name', 'Belgium'), ('avg', '4020000000'), ('min', '4020000000'), ('max', '4020000000')]
# [('name', 'Bulgaria'), ('avg', '9808000'), ('min', '9808000'), ('max', '9808000')]
# [('name', 'Canada'), ('avg', '1426000000'), ('min', '-149000000'), ('max', '2498000000')]
# [('name', 'Cayman Islands'), ('avg', '34880992500'), ('min', '49985000'), ('max', '69712000000')]
# [('name', 'Crimean Peninsula'), ('avg', '-488610000'), ('min', '-488610000'), ('max', '-488610000')]
# [('name', 'Croatia'), ('avg', '-2961630000'), ('min', '-2961630000'), ('max', '-2961630000')]
# [('name', 'Cyprus'), ('avg', '47675120'), ('min', '8150240'), ('max', '87200000')]
# [('name', 'Czech Republic'), ('avg', '561955581.109467455621302'), ('min', '-5171656000'), ('max', '30613000000')]
# [('name', 'Czechoslovakia'), ('avg', '-1637000'), ('min', '-1637000'), ('max', '-1637000')]
# [('name', 'Denmark'), ('avg', '1992885875'), ('min', '-855000000'), ('max', '13877000000')]
# [('name', 'Faroe Islands'), ('avg', '1074912000'), ('min', '1074912000'), ('max', '1074912000')]
# [('name', 'Finland'), ('avg', '836235400'), ('min', '-1100000000'), ('max', '5127000000')]
# [('name', 'France'), ('avg', '2855231300'), ('min', '114600000'), ('max', '6810000000')]
# [('name', 'Germany'), ('avg', '3686841473.684210526315789'), ('min', '-181518000'), ('max', '12902000000')]
# [('name', 'Greece'), ('avg', '287471000'), ('min', '216500000'), ('max', '385600000')]
# [('name', 'Hungary'), ('avg', '307905000000'), ('min', '307905000000'), ('max', '307905000000')]
# [('name', 'Israel'), ('avg', '87200000'), ('min', '87200000'), ('max', '87200000')]
# [('name', 'Italy'), ('avg', '1087500000'), ('min', '473000000'), ('max', '1702000000')]
# [('name', 'Japan'), ('avg', '613255182222.222222222222222'), ('min', '-5104000000'), ('max', '2853971000000')]
# [('name', 'Jersey'), ('avg', '280472000'), ('min', '279000000'), ('max', '281944000')]
# [('name', 'Kazakhstan'), ('avg', '2710000000'), ('min', '2710000000'), ('max', '2710000000')]
# [('name', 'Kingdom of the Netherlands'), ('avg', '790600000'), ('min', '790600000'), ('max', '790600000')]
# [('name', 'Latvia'), ('avg', '13800000'), ('min', '13800000'), ('max', '13800000')]
# [('name', 'Luxembourg'), ('avg', '293952800'), ('min', '-73000000'), ('max', '1011000000')]
# [('name', 'Netherlands'), ('avg', '2752035357.142857142857143'), ('min', '-9677000'), ('max', '18324000000')]
# [('name', 'Norway'), ('avg', '3899335166.666666666666667'), ('min', '54100000'), ('max', '18848000000')]
# [('name', "People's Republic of China"), ('avg', '71484820490.857142857142857'), ('min', '33685000'), ('max', '390822000000')]
# [('name', 'Poland'), ('avg', '2048680015.78'), ('min', '141040047.34'), ('max', '5554000000')]
# [('name', 'Russia'), ('avg', '51122627077.777777777777778'), ('min', '-48465118000'), ('max', '1702100000000')]
# [('name', 'Saudi Arabia'), ('avg', '674871000000'), ('min', '674871000000'), ('max', '674871000000')]
# [('name', 'Serbia'), ('avg', '297301000'), ('min', '32312000'), ('max', '562290000')]
# [('name', 'Slovakia'), ('avg', '91232000'), ('min', '-2090000'), ('max', '344172000')]
# [('name', 'Slovenia'), ('avg', '-44588000'), ('min', '-44588000'), ('max', '-44588000')]
# [('name', 'South Korea'), ('avg', '7348055899750'), ('min', '97000000'), ('max', '29240000000000')]
# [('name', 'Soviet Union'), ('avg', '647202600'), ('min', '-23400000'), ('max', '1300000000')]
# [('name', 'Spain'), ('avg', '5725084000'), ('min', '-560957000'), ('max', '12640000000')]
# [('name', 'Sweden'), ('avg', '4502891666.666666666666667'), ('min', '-855000000'), ('max', '15493000000')]
# [('name', 'Switzerland'), ('avg', '12997502833.333333333333333'), ('min', '22317000'), ('max', '50998000000')]
# [('name', 'Taiwan'), ('avg', '50573411196.5'), ('min', '24716786'), ('max', '174939501000')]
# [('name', 'Turkey'), ('avg', '14275366666.666666666666667'), ('min', '94100000'), ('max', '41578000000')]
# [('name', 'Ukraine'), ('avg', '6466498000'), ('min', '-77197000'), ('max', '13010193000')]
# [('name', 'United Kingdom'), ('avg', '2259337924.428571428571429'), ('min', '-1161000000'), ('max', '14792000000')]
# [('name', 'United States of America'), ('avg', '10150369915.43953488372093'), ('min', '-12150000000'), ('max', '113012000000')]
# 49

# %%
#min max and average of total assets for each country
q = f"""
select ?name (avg(?v) as ?avg) (min(?v) as ?min) (max(?v) as ?max) where{{
# ?country <http://schema.org/name> ?name .
    {{
        select ?country ?v where{{
            # ?company wdt:P31 wd:Q4830453 .
            # ?company wdt:P2403 ?v .
            # ?company wdt:P17 ?country .
        }}
    }}

}}
group by ?name
order by asc (?name)
"""
print("Total Assets")
run_query(q)
# Out:
# Total Assets
# [('name', 'Algeria'), ('avg', '230000000000'), ('min', '230000000000'), ('max', '230000000000')]
# [('name', 'Argentina'), ('avg', '436341125'), ('min', '436341125'), ('max', '436341125')]
# [('name', 'Australia'), ('avg', '56002699549'), ('min', '12399098'), ('max', '111993000000')]
# [('name', 'Austria'), ('avg', '10123721200'), ('min', '1490000000'), ('max', '32112000000')]
# [('name', 'Austria-Hungary'), ('avg', '196766000'), ('min', '196766000'), ('max', '196766000')]
# [('name', 'Austrian Empire'), ('avg', '196766000'), ('min', '196766000'), ('max', '196766000')]
# [('name', 'Bahrain'), ('avg', '8467304000'), ('min', '8467304000'), ('max', '8467304000')]
# [('name', 'Belarus'), ('avg', '1911946000'), ('min', '1911946000'), ('max', '1911946000')]
# [('name', 'Belgium'), ('avg', '275200000000'), ('min', '275200000000'), ('max', '275200000000')]
# [('name', 'Brazil'), ('avg', '68810000000'), ('min', '68810000000'), ('max', '68810000000')]
# [('name', 'British Virgin Islands'), ('avg', '12399098'), ('min', '12399098'), ('max', '12399098')]
# [('name', 'Bulgaria'), ('avg', '1160890000'), ('min', '1160890000'), ('max', '1160890000')]
# [('name', 'Canada'), ('avg', '7803000000'), ('min', '1640000000'), ('max', '17881000000')]
# [('name', 'Cayman Islands'), ('avg', '1151327762500'), ('min', '1496525000'), ('max', '2301159000000')]
# [('name', 'Crimean Peninsula'), ('avg', '126869333000'), ('min', '126869333000'), ('max', '126869333000')]
# [('name', 'Croatia'), ('avg', '675233145000'), ('min', '675233145000'), ('max', '675233145000')]
# [('name', 'Cyprus'), ('avg', '116321213'), ('min', '116321213'), ('max', '116321213')]
# [('name', 'Czech Republic'), ('avg', '15997489927.87621359223301'), ('min', '0'), ('max', '1458650000000')]
# [('name', 'Czechoslovakia'), ('avg', '196766000'), ('min', '196766000'), ('max', '196766000')]
# [('name', 'Denmark'), ('avg', '44711833988.526315789473684'), ('min', '86933'), ('max', '404180000000')]
# [('name', 'Finland'), ('avg', '327588000000'), ('min', '39517000000'), ('max', '615659000000')]
# [('name', 'France'), ('avg', '53922831481.818181818181818'), ('min', '111133000'), ('max', '230978000000')]
# [('name', 'German Reich'), ('avg', '82339839'), ('min', '82339839'), ('max', '82339839')]
# [('name', 'Germany'), ('avg', '52519690751.89375'), ('min', '1374854.72'), ('max', '409732000000')]
# [('name', 'Greece'), ('avg', '8001268666.666666666666667'), ('min', '2320206000'), ('max', '14112000000')]
# [('name', 'Hong Kong'), ('avg', '8289924000000'), ('min', '8289924000000'), ('max', '8289924000000')]
# [('name', 'Hungary'), ('avg', '2411893000000'), ('min', '720000000000'), ('max', '4103786000000')]
# [('name', 'Ireland'), ('avg', '68567622000'), ('min', '43749244000'), ('max', '93386000000')]
# [('name', 'Israel'), ('avg', '243886000'), ('min', '243886000'), ('max', '243886000')]
# [('name', 'Italy'), ('avg', '274456633000'), ('min', '69899000'), ('max', '601300000000')]
# [('name', 'Japan'), ('avg', '10170190707000'), ('min', '1412070000'), ('max', '47427597000000')]
# [('name', 'Jersey'), ('avg', '10233529000'), ('min', '3089058000'), ('max', '17378000000')]
# [('name', 'Kingdom of the Netherlands'), ('avg', '9158900000'), ('min', '9158900000'), ('max', '9158900000')]
# [('name', 'Latvia'), ('avg', '883047755'), ('min', '1550330'), ('max', '2642642800')]
# [('name', 'Lithuania'), ('avg', '2200790000'), ('min', '2200790000'), ('max', '2200790000')]
# [('name', 'Luxembourg'), ('avg', '2999119894.428571428571429'), ('min', '174304057'), ('max', '7529000000')]
# [('name', 'Monaco'), ('avg', '2174638047.225'), ('min', '15424094.45'), ('max', '4333852000')]
# [('name', 'Netherlands'), ('avg', '86092635450'), ('min', '37030000'), ('max', '845000000000')]
# [('name', 'Norway'), ('avg', '740150872000'), ('min', '42988000'), ('max', '2793294000000')]
# [('name', "People's Republic of China"), ('avg', '4439947726959.48875'), ('min', '3727000000'), ('max', '33345058000000')]
# [('name', 'Poland'), ('avg', '26236737333.333333333333333'), ('min', '1872212000'), ('max', '71202000000')]
# [('name', 'Portugal'), ('avg', '8194637000'), ('min', '8194637000'), ('max', '8194637000')]
# [('name', 'Russia'), ('avg', '1292729712609.523809523809524'), ('min', '50858000'), ('max', '36016000000000')]
# [('name', 'Saudi Arabia'), ('avg', '104463601437.86'), ('min', '32525893'), ('max', '1494126000000')]
# [('name', 'Slovakia'), ('avg', '878583452.875'), ('min', '33649623'), ('max', '3077672000')]
# [('name', 'Slovenia'), ('avg', '1012329000'), ('min', '1012329000'), ('max', '1012329000')]
# [('name', 'South Korea'), ('avg', '53747392301544.4'), ('min', '6450000000'), ('max', '262174300000000')]
# [('name', 'Soviet Union'), ('avg', '17608368500'), ('min', '1000000000'), ('max', '50282085000')]
# [('name', 'Spain'), ('avg', '272700152875'), ('min', '100000'), ('max', '1340000000000')]
# [('name', 'Sweden'), ('avg', '97100500000'), ('min', '75411000000'), ('max', '118790000000')]
# [('name', 'Switzerland'), ('avg', '127131876666.666666666666667'), ('min', '284824000'), ('max', '439299000000')]
# [('name', 'Taiwan'), ('avg', '318177620333.333333333333333'), ('min', '182373217000'), ('max', '433057069000')]
# [('name', 'Thailand'), ('avg', '218577276.9'), ('min', '218577276.9'), ('max', '218577276.9')]
# [('name', 'Togo'), ('avg', '2797000000'), ('min', '2797000000'), ('max', '2797000000')]
# [('name', 'Ukraine'), ('avg', '12768285500'), ('min', '1072855000'), ('max', '24463716000')]
# [('name', 'United Arab Emirates'), ('avg', '60609617000'), ('min', '8467304000'), ('max', '112751930000')]
# [('name', 'United Kingdom'), ('avg', '319181544833'), ('min', '135646163'), ('max', '2374986000000')]
# [('name', 'United States of America'), ('avg', '212870364610.982424778761062'), ('min', '1'), ('max', '3960490000000')]
# 58

# %%
#min max and average of market capital for each country
q = f"""
select ?name (avg(?v) as ?avg) (min(?v) as ?min) (max(?v) as ?max) where{{
# ?country <http://schema.org/name> ?name .
    {{
        select ?country ?v where{{
            # ?company wdt:P31 wd:Q4830453 .
            # ?company wdt:P2226 ?v .
            # ?company wdt:P17 ?country .
        }}
    }}

}}
group by ?name
order by asc (?name)
"""
print("Market capital")
run_query(q)
# Out:
# Market capital
# [('name', 'Argentina'), ('avg', '602938304'), ('min', '602938304'), ('max', '602938304')]
# [('name', 'Austria'), ('avg', '7230000000'), ('min', '3500000000'), ('max', '10960000000')]
# [('name', 'Canada'), ('avg', '17810177452.666666666666667'), ('min', '648532358'), ('max', '45900000000')]
# [('name', 'Czech Republic'), ('avg', '138800000000'), ('min', '7100000000'), ('max', '286200000000')]
# [('name', 'Denmark'), ('avg', '142452000000'), ('min', '25256000000'), ('max', '289600000000')]
# [('name', 'Finland'), ('avg', '220628500000'), ('min', '26257000000'), ('max', '415000000000')]
# [('name', 'France'), ('avg', '30570379928.142857142857143'), ('min', '157659497'), ('max', '139000000000')]
# [('name', 'Germany'), ('avg', '40829082512.5'), ('min', '111760000'), ('max', '139800000000')]
# [('name', 'Greece'), ('avg', '3896025.7'), ('min', '3896025.7'), ('max', '3896025.7')]
# [('name', 'India'), ('avg', '107711666666.666666666666667'), ('min', '4635000000'), ('max', '300500000000')]
# [('name', 'Israel'), ('avg', '233397111.111111111111111'), ('min', '25710000'), ('max', '883584000')]
# [('name', 'Japan'), ('avg', '176578250000'), ('min', '8414000000'), ('max', '500000000000')]
# [('name', 'Kingdom of the Netherlands'), ('avg', '9431200000'), ('min', '9431200000'), ('max', '9431200000')]
# [('name', 'Luxembourg'), ('avg', '32000000000'), ('min', '32000000000'), ('max', '32000000000')]
# [('name', 'Netherlands'), ('avg', '16371469400'), ('min', '16707000'), ('max', '35600000000')]
# [('name', 'Norway'), ('avg', '22800000000'), ('min', '22800000000'), ('max', '22800000000')]
# [('name', "People's Republic of China"), ('avg', '243028851565'), ('min', '57703130'), ('max', '486000000000')]
# [('name', 'Russia'), ('avg', '731755800000'), ('min', '6858000000'), ('max', '3100000000000')]
# [('name', 'Saudi Arabia'), ('avg', '2458000000000'), ('min', '2458000000000'), ('max', '2458000000000')]
# [('name', 'Soviet Union'), ('avg', '7920000000'), ('min', '7920000000'), ('max', '7920000000')]
# [('name', 'Spain'), ('avg', '38105000000'), ('min', '38105000000'), ('max', '38105000000')]
# [('name', 'Sweden'), ('avg', '58889000000'), ('min', '37774000000'), ('max', '80004000000')]
# [('name', 'Switzerland'), ('avg', '205056500000'), ('min', '172750000000'), ('max', '237363000000')]
# [('name', 'Taiwan'), ('avg', '56280000000'), ('min', '56280000000'), ('max', '56280000000')]
# [('name', 'United Kingdom'), ('avg', '116200000000'), ('min', '47000000000'), ('max', '185400000000')]
# [('name', 'United States of America'), ('avg', '411943146923'), ('min', '500000'), ('max', '2470000000000')]
# 26

# %%
#we need to use several subqueries if we want to do everything in sparql

#get for each country: business and how many businesses it owns in other countries
q1 = f"""
select ?country ?company (count(*) as ?owned) where{{
# ?company wdt:P31 wd:Q4830453 ;
    wdt:P1830 ?anotherCompany ;
    wdt:P17 ?country .
# ?anotherCompany wdt:P31 wd:Q4830453 ;
    wdt:P17 ?anotherCountry .
    
filter(?country != ?anotherCountry) .
}}
group by ?country ?company
"""
#having q1, select for each returned country the greates amount of businesses owned in other countries across all companies
q2 = f"""
select ?country (max(?owned) as ?max) where{{

    {{
        select ?country ?company (count(*) as ?owned) where{{

# ?company wdt:P31 wd:Q4830453 ;

    wdt:P1830 ?anotherCompany ;

    wdt:P17 ?country .

# ?anotherCompany wdt:P31 wd:Q4830453 ;

    wdt:P17 ?anotherCountry .

    

filter(?country != ?anotherCountry) .

}}

group by ?country ?company



    }}
}}
group by ?country
"""
#this is a repeat of q1, with different names for the variables
q3 = f"""
select ?c ?ct (count(*) as ?tot) where{{
# ?c wdt:P31 wd:Q4830453 ;
    wdt:P1830 ?anotherCompany ;
    wdt:P17 ?ct .
# ?anotherCompany wdt:P31 wd:Q4830453 ;
    wdt:P17 ?anotherCountry .
    
filter(?ct != ?anotherCountry) .
}}
group by ?c ?ct
"""

#having for each country the greatest number of businesses from another country that a certain local business owns select ?country (max(?owned) as ?max) where{{



    {{

        select ?country ?company (count(*) as ?owned) where{{

# ?company wdt:P31 wd:Q4830453 ;

    wdt:P1830 ?anotherCompany ;

    wdt:P17 ?country .

# ?anotherCompany wdt:P31 wd:Q4830453 ;

    wdt:P17 ?anotherCountry .

    

filter(?country != ?anotherCountry) .

}}

group by ?country ?company




    }}

}}

group by ?country



#and having the list of each business and the number of non local businesses it owns, along with its original country select ?c ?ct (count(*) as ?tot) where{{

# ?c wdt:P31 wd:Q4830453 ;

    wdt:P1830 ?anotherCompany ;

    wdt:P17 ?ct .

# ?anotherCompany wdt:P31 wd:Q4830453 ;

    wdt:P17 ?anotherCountry .

    

filter(?ct != ?anotherCountry) .

}}

group by ?c ?ct



#we simply compare country and count in the 2 sets, when they match we return the corresponding business
q4 = f"""
select ?countryName ?companyName ?max where{{
# ?c <http://schema.org/name> ?companyName .
# ?country <http://schema.org/name> ?countryName .
    {{
        select ?c ?ct (count(*) as ?tot) where{{

# ?c wdt:P31 wd:Q4830453 ;

    wdt:P1830 ?anotherCompany ;

    wdt:P17 ?ct .

# ?anotherCompany wdt:P31 wd:Q4830453 ;

    wdt:P17 ?anotherCountry .

    

filter(?ct != ?anotherCountry) .

}}

group by ?c ?ct



    }}
    
    {{
        select ?country (max(?owned) as ?max) where{{



    {{

        select ?country ?company (count(*) as ?owned) where{{

# ?company wdt:P31 wd:Q4830453 ;

    wdt:P1830 ?anotherCompany ;

    wdt:P17 ?country .

# ?anotherCompany wdt:P31 wd:Q4830453 ;

    wdt:P17 ?anotherCountry .

    

filter(?country != ?anotherCountry) .

}}

group by ?country ?company




    }}

}}

group by ?country



    }}
filter(?tot = ?max && ?ct = ?country) .
}}
"""
run_query(q4)
# Out:
# [('countryName', 'Sweden'), ('companyName', 'Electrolux'), ('max', '5')]
# [('countryName', 'German Reich'), ('companyName', 'AG für Verkehrswesen'), ('max', '25')]
# [('countryName', 'Australia'), ('companyName', 'BHP Group'), ('max', '1')]
# [('countryName', 'Switzerland'), ('companyName', 'Richemont'), ('max', '4')]
# [('countryName', 'Spain'), ('companyName', 'Telefónica'), ('max', '5')]
# [('countryName', 'United States of America'), ('companyName', 'The Walt Disney Company'), ('max', '6')]
# [('countryName', "People's Republic of China"), ('companyName', 'Alibaba Group'), ('max', '3')]
# [('countryName', 'Russia'), ('companyName', 'Sberbank of Russia'), ('max', '2')]
# [('countryName', 'Netherlands'), ('companyName', 'Heineken'), ('max', '10')]
# [('countryName', 'Canada'), ('companyName', 'Corel'), ('max', '3')]
# [('countryName', 'Ireland'), ('companyName', 'Accenture'), ('max', '1')]
# [('countryName', 'Algeria'), ('companyName', 'Cevital'), ('max', '2')]
# [('countryName', 'British Virgin Islands'), ('companyName', 'White Surrey'), ('max', '1')]
# [('countryName', 'Austria'), ('companyName', 'A1 Telekom Austria Group'), ('max', '2')]
# [('countryName', 'Brazil'), ('companyName', 'Anheuser-Busch InBev'), ('max', '9')]
# [('countryName', 'Belgium'), ('companyName', 'Anheuser-Busch InBev'), ('max', '9')]
# [('countryName', 'Japan'), ('companyName', 'Sony'), ('max', '10')]
# [('countryName', 'Malaysia'), ('companyName', 'Axiata'), ('max', '3')]
# [('countryName', 'Singapore'), ('companyName', 'GIC Private Limited'), ('max', '3')]
# [('countryName', 'South Africa'), ('companyName', 'De Beers'), ('max', '1')]
# [('countryName', 'Taiwan'), ('companyName', 'Acer Inc.'), ('max', '2')]
# [('countryName', 'Turkey'), ('companyName', 'Yamaha Corporation'), ('max', '4')]
# [('countryName', 'India'), ('companyName', 'Tata Motors'), ('max', '1')]
# [('countryName', 'France'), ('companyName', 'LVMH'), ('max', '10')]
# [('countryName', 'Czech Republic'), ('companyName', 'Škoda Auto'), ('max', '3')]
# [('countryName', 'United States of America'), ('companyName', 'Ford Motor Company'), ('max', '6')]
# [('countryName', 'Czechoslovakia'), ('companyName', 'ČKD'), ('max', '1')]
# [('countryName', 'Denmark'), ('companyName', 'Carlsberg Group'), ('max', '10')]
# [('countryName', 'Poland'), ('companyName', 'PKN Orlen'), ('max', '1')]
# [('countryName', 'South Korea'), ('companyName', 'Daewoo'), ('max', '1')]
# [('countryName', 'Romania'), ('companyName', 'Citibank'), ('max', '1')]
# [('countryName', 'Croatia'), ('companyName', 'Agrokor'), ('max', '3')]
# [('countryName', 'Norway'), ('companyName', 'Telenor'), ('max', '6')]
# [('countryName', 'Israel'), ('companyName', 'Bezeq'), ('max', '1')]
# [('countryName', 'United Kingdom'), ('companyName', 'Tesco'), ('max', '8')]
# [('countryName', 'Mexico'), ('companyName', 'América Móvil'), ('max', '2')]
# [('countryName', 'Finland'), ('companyName', 'Amer Sports'), ('max', '5')]
# [('countryName', 'Thailand'), ('companyName', 'Charoen Pokphand'), ('max', '1')]
# [('countryName', 'United Arab Emirates'), ('companyName', 'Emirates Telecommunications Corporation'), ('max', '2')]
# [('countryName', 'Czech Republic'), ('companyName', 'EP Infrastructure'), ('max', '3')]
# [('countryName', 'Ukraine'), ('companyName', 'Naftogaz'), ('max', '1')]
# [('countryName', 'Kingdom of the Netherlands'), ('companyName', 'CZI Holdings'), ('max', '2')]
# [('countryName', 'Poland'), ('companyName', 'PKP Cargo'), ('max', '1')]
# [('countryName', 'Slovakia'), ('companyName', 'DOAS SK'), ('max', '2')]
# [('countryName', 'British Virgin Islands'), ('companyName', 'Euro Capital Alliance'), ('max', '1')]
# [('countryName', 'Jersey'), ('companyName', 'Penta Investments Limited'), ('max', '7')]
# [('countryName', 'Cyprus'), ('companyName', 'Penta Investments Limited'), ('max', '4')]
# [('countryName', 'Slovakia'), ('companyName', 'Tatry Mountain Resorts'), ('max', '2')]
# [('countryName', 'The Bahamas'), ('companyName', 'Camron Investment Management'), ('max', '1')]
# [('countryName', 'Austria'), ('companyName', 'Benteler International'), ('max', '2')]
# [('countryName', 'Italy'), ('companyName', 'Lavazza'), ('max', '4')]
# [('countryName', 'Guernsey'), ('companyName', 'Buteo Rapax'), ('max', '1')]
# [('countryName', 'Liechtenstein'), ('companyName', 'Nemo Fund'), ('max', '3')]
# [('countryName', 'Ireland'), ('companyName', 'Facebook International Operations Limited'), ('max', '1')]
# [('countryName', 'Russia'), ('companyName', 'Basic Element'), ('max', '2')]
# [('countryName', 'Czech Republic'), ('companyName', 'EP Power Europe'), ('max', '3')]
# [('countryName', 'British Virgin Islands'), ('companyName', 'China United Association International Funding Centre'), ('max', '1')]
# [('countryName', 'Austria'), ('companyName', 'Strabag Holding'), ('max', '2')]
# [('countryName', 'Cayman Islands'), ('companyName', 'Manchester United Plc'), ('max', '1')]
# [('countryName', 'Germany'), ('companyName', 'Aachen Münchener'), ('max', '7')]
# [('countryName', 'British Virgin Islands'), ('companyName', 'Hengxin Enterprises'), ('max', '1')]
# [('countryName', 'British Virgin Islands'), ('companyName', 'USM Holdings'), ('max', '1')]
# [('countryName', 'Hungary'), ('companyName', 'Cloud Network Technology'), ('max', '2')]
# [('countryName', 'British Virgin Islands'), ('companyName', 'Eridanus Investments'), ('max', '1')]
# [('countryName', 'British Virgin Islands'), ('companyName', 'Orozco Holdings'), ('max', '1')]
# [('countryName', 'Bermuda'), ('companyName', 'ACP Partners Limited'), ('max', '1')]
# [('countryName', 'Guernsey'), ('companyName', 'Pratincole Investments'), ('max', '1')]
# [('countryName', 'Hong Kong'), ('companyName', 'China International Group Corporation'), ('max', '3')]
# [('countryName', 'Guernsey'), ('companyName', 'Macquarie European Infrastructure Fund II'), ('max', '1')]
# [('countryName', 'Luxembourg'), ('companyName', 'NexGen'), ('max', '13')]
# [('countryName', 'Estonia'), ('companyName', 'Luminor Bank'), ('max', '1')]
# [('countryName', 'British Virgin Islands'), ('companyName', 'Lilyvale Limited'), ('max', '1')]
# [('countryName', 'Ireland'), ('companyName', 'Gosford Capital Designated Activity Company'), ('max', '1')]
# [('countryName', 'Cayman Islands'), ('companyName', 'CZ Investments'), ('max', '1')]
# [('countryName', 'British Virgin Islands'), ('companyName', 'BXR Group Limited'), ('max', '1')]
# [('countryName', 'Slovakia'), ('companyName', 'Supernius'), ('max', '2')]
# [('countryName', 'British Virgin Islands'), ('companyName', 'Faltha Investment'), ('max', '1')]
# [('countryName', 'United Kingdom of Great Britain and Ireland'), ('companyName', 'Brazilian Warrant Agency and Finance Co'), ('max', '1')]
# [('countryName', 'Cayman Islands'), ('companyName', 'Tritton Development Fund'), ('max', '1')]
# [('countryName', 'Lebanon'), ('companyName', 'Globe Re Sal'), ('max', '1')]
# [('countryName', 'Marshall Islands'), ('companyName', 'Maranex Finance'), ('max', '1')]
# [('countryName', 'Cayman Islands'), ('companyName', 'BTO Ripple Holdings'), ('max', '1')]
# [('countryName', 'Malta'), ('companyName', 'Priveq Funds'), ('max', '2')]
# [('countryName', 'Cayman Islands'), ('companyName', 'BT Global Investments'), ('max', '1')]
# [('countryName', 'Guernsey'), ('companyName', 'Conitor Terra'), ('max', '1')]
# [('countryName', 'British Virgin Islands'), ('companyName', 'Vixon Resources'), ('max', '1')]
# [('countryName', 'British Virgin Islands'), ('companyName', 'Chelton Properties'), ('max', '1')]
# [('countryName', 'Guernsey'), ('companyName', 'Genesis Private Equity Fund III'), ('max', '1')]
# [('countryName', 'Cayman Islands'), ('companyName', 'Chorus Explorers Fund I SPC'), ('max', '1')]
# [('countryName', 'Union of South Africa'), ('companyName', 'Union Corporation'), ('max', '1')]
# 90

# %%
#in the last query there are countries that looks like aren't existing anymore, let's look if also the companies have dissolved
#this was another property found earlier
dissolved = 'wdt:P576'
#let's check what values it has
q = f"""
select distinct ?state where{{
# ?company wdt:P31 wd:Q4830453 ;
    wdt:P576 ?state .
}}
limit 100
"""
run_query(q)
# Out:
# [('state', '2003-01-01T00:00:00Z')]
# [('state', '1995-01-01T00:00:00Z')]
# [('state', '1954-01-01T00:00:00Z')]
# [('state', '1923-01-01T00:00:00Z')]
# [('state', '2008-01-01T00:00:00Z')]
# [('state', '2005-10-01T00:00:00Z')]
# [('state', '2009-01-01T00:00:00Z')]
# [('state', '1998-01-01T00:00:00Z')]
# [('state', '2013-08-16T00:00:00Z')]
# [('state', '2014-01-01T00:00:00Z')]
# [('state', '1996-01-01T00:00:00Z')]
# [('state', '1906-01-01T00:00:00Z')]
# [('state', '1992-01-01T00:00:00Z')]
# [('state', '1925-01-01T00:00:00Z')]
# [('state', '1973-01-01T00:00:00Z')]
# [('state', '2012-11-01T00:00:00Z')]
# [('state', '2020-11-01T00:00:00Z')]
# [('state', '1972-01-27T00:00:00Z')]
# [('state', '1941-01-01T00:00:00Z')]
# [('state', '1878-01-01T00:00:00Z')]
# [('state', '1999-01-01T00:00:00Z')]
# [('state', '2012-01-01T00:00:00Z')]
# [('state', '1983-01-01T00:00:00Z')]
# [('state', '2011-01-01T00:00:00Z')]
# [('state', '2013-01-01T00:00:00Z')]
# [('state', '1990-01-01T00:00:00Z')]
# [('state', '2017-01-01T00:00:00Z')]
# [('state', '2016-01-01T00:00:00Z')]
# [('state', '2016-06-01T00:00:00Z')]
# [('state', '1926-01-01T00:00:00Z')]
# [('state', '1832-01-01T00:00:00Z')]
# [('state', '1963-01-01T00:00:00Z')]
# [('state', '1989-01-01T00:00:00Z')]
# [('state', '2015-01-10T00:00:00Z')]
# [('state', '1966-01-01T00:00:00Z')]
# [('state', '1980-01-01T00:00:00Z')]
# [('state', '1988-11-04T00:00:00Z')]
# [('state', '2019-12-31T00:00:00Z')]
# [('state', '1994-01-01T00:00:00Z')]
# [('state', '2006-01-01T00:00:00Z')]
# [('state', '2002-01-01T00:00:00Z')]
# [('state', '1982-01-01T00:00:00Z')]
# [('state', '1971-01-01T00:00:00Z')]
# [('state', '1960-01-01T00:00:00Z')]
# [('state', '1984-01-01T00:00:00Z')]
# [('state', '1917-01-01T00:00:00Z')]
# [('state', '2000-02-09T00:00:00Z')]
# [('state', '2016-05-18T00:00:00Z')]
# [('state', '2018-07-31T00:00:00Z')]
# [('state', '2000-01-01T00:00:00Z')]
# [('state', '2005-01-01T00:00:00Z')]
# [('state', '2015-03-11T00:00:00Z')]
# [('state', '2022-01-01T00:00:00Z')]
# [('state', '1993-01-01T00:00:00Z')]
# [('state', '1927-01-01T00:00:00Z')]
# [('state', '2000-06-09T00:00:00Z')]
# [('state', '1976-01-01T00:00:00Z')]
# [('state', '1985-01-01T00:00:00Z')]
# [('state', '2016-08-26T00:00:00Z')]
# [('state', '1987-01-01T00:00:00Z')]
# [('state', '2013-12-01T00:00:00Z')]
# [('state', '2015-01-01T00:00:00Z')]
# [('state', '2015-01-31T00:00:00Z')]
# [('state', '2017-05-31T00:00:00Z')]
# [('state', '2015-03-13T00:00:00Z')]
# [('state', '2016-03-31T00:00:00Z')]
# [('state', '1957-03-01T00:00:00Z')]
# [('state', '2010-01-01T00:00:00Z')]
# [('state', '2005-02-28T00:00:00Z')]
# [('state', '2002-09-16T00:00:00Z')]
# [('state', '1874-06-01T00:00:00Z')]
# [('state', '2015-02-09T00:00:00Z')]
# [('state', '1934-01-01T00:00:00Z')]
# [('state', '2010-04-01T00:00:00Z')]
# [('state', '2001-07-01T00:00:00Z')]
# [('state', '2008-11-01T00:00:00Z')]
# [('state', '1956-01-01T00:00:00Z')]
# [('state', '2015-01-22T00:00:00Z')]
# [('state', '2011-01-20T00:00:00Z')]
# [('state', '1965-01-01T00:00:00Z')]
# [('state', '1950-01-01T00:00:00Z')]
# [('state', '2007-01-01T00:00:00Z')]
# [('state', '1943-01-01T00:00:00Z')]
# [('state', '1994-04-29T00:00:00Z')]
# [('state', '2020-08-21T00:00:00Z')]
# [('state', '2013-08-02T00:00:00Z')]
# [('state', '1974-01-01T00:00:00Z')]
# [('state', '2018-01-01T00:00:00Z')]
# [('state', '1920-01-01T00:00:00Z')]
# [('state', '1938-01-01T00:00:00Z')]
# [('state', '1935-01-01T00:00:00Z')]
# [('state', '1945-01-01T00:00:00Z')]
# [('state', '2012-10-01T00:00:00Z')]
# [('state', '2015-10-26T00:00:00Z')]
# [('state', '1937-03-01T00:00:00Z')]
# [('state', '1922-01-01T00:00:00Z')]
# [('state', '1967-01-01T00:00:00Z')]
# [('state', '1808-01-01T00:00:00Z')]
# [('state', '1991-06-30T00:00:00Z')]
# [('state', '1968-01-01T00:00:00Z')]
# 100

# %%
#dissolved indicates actually a date, probably the date in which a company was dissolved
#let's check if Microsoft was dissolved
q = f"""
select ?name where{{
wd:Q2283 <http://schema.org/name> ?name
filter not exists{{
        wd:Q2283 wdt:P576 ?date
    }}
}}
"""
run_query(q)
# Out:
# [('name', 'Microsoft')]
# 1

# %%
#let's try and see if blockbuster is present and was dissolved
q = f"""
select ?name ?dissolution where{{
# ?company wdt:P31 wd:Q4830453 ;
    <http://schema.org/name> ?name ;
    wdt:P576 ?dissolution
filter regex(?name, 'blockbuster', 'i')
}}
"""
run_query(q)
# Out:
# [('name', 'Blockbuster LLC'), ('dissolution', '2014-01-12T00:00:00Z')]
# 1

# %%
#let's see the 10 companies that dissolved most recently
q = f"""
select ?name ?dissolution where{{
# ?company wdt:P31 wd:Q4830453 ;
    <http://schema.org/name> ?name ;
    wdt:P576 ?dissolution
}}
order by desc(?dissolution)
limit 10
"""
run_query(q)
# Out:
# [('name', 'Interactive Data Visualization Inc.'), ('dissolution', '2021-07-14T00:00:00Z')]
# [('name', 'DB Dienstleistungen'), ('dissolution', 'nodeID://b383265')]
# [('name', 'Saluka Investment'), ('dissolution', 'nodeID://b363939')]
# [('name', 'Cespo Holdings'), ('dissolution', 'nodeID://b312546')]
# [('name', "Dal Co'"), ('dissolution', 'nodeID://b308573')]
# [('name', 'Nimura and Sato'), ('dissolution', 'nodeID://b273764')]
# [('name', 'Goji Electronics'), ('dissolution', 'nodeID://b273278')]
# [('name', 'Domus'), ('dissolution', 'nodeID://b244602')]
# [('name', 'Bayer CropScience'), ('dissolution', '2022-01-01T00:00:00Z')]
# [('name', 'Liberbank'), ('dissolution', '2021-07-30T00:00:00Z')]
# 10

# %%
#what are the top 10 countries that have seen the most companies dissolve?
q = f"""
select ?countryName (count(?dissolution) as ?howMany) where{{
# ?company wdt:P31 wd:Q4830453 ;
    wdt:P576 ?dissolution ;
    wdt:P17 ?country .
# ?country <http://schema.org/name> ?countryName
}}
group by ?countryName
order by desc(?howMany)
limit 10
"""
run_query(q)
# Out:
# [('countryName', 'United States of America'), ('howMany', '1485')]
# [('countryName', 'Germany'), ('howMany', '1235')]
# [('countryName', 'Italy'), ('howMany', '820')]
# [('countryName', 'United Kingdom'), ('howMany', '784')]
# [('countryName', 'France'), ('howMany', '325')]
# [('countryName', 'Norway'), ('howMany', '263')]
# [('countryName', 'Czech Republic'), ('howMany', '230')]
# [('countryName', 'Belgium'), ('howMany', '182')]
# [('countryName', 'Sweden'), ('howMany', '159')]
# [('countryName', 'Japan'), ('howMany', '148')]
# 10

# %%
#and finally, the top 10 countries for number of companies still active
q = f"""
select ?countryName (count(*) as ?howMany) where{{
# ?company wdt:P31 wd:Q4830453 ;
    wdt:P17 ?country .
filter not exists {{
        # ?company wdt:P576 ?dissolution
    }}
# ?country <http://schema.org/name> ?countryName
}}
group by ?countryName
order by desc(?howMany)
limit 10
"""
run_query(q)
# Out:
# [('countryName', 'United States of America'), ('howMany', '20819')]
# [('countryName', 'Czech Republic'), ('howMany', '20579')]
# [('countryName', 'Germany'), ('howMany', '10317')]
# [('countryName', 'Japan'), ('howMany', '7254')]
# [('countryName', 'United Kingdom'), ('howMany', '7023')]
# [('countryName', 'Sweden'), ('howMany', '4115')]
# [('countryName', 'Slovakia'), ('howMany', '3996')]
# [('countryName', 'France'), ('howMany', '3445')]
# [('countryName', 'Brazil'), ('howMany', '3334')]
# [('countryName', 'Norway'), ('howMany', '3108')]
# 10

# %%
#get for each country: business and how many businesses it owns in other countries
#REPEAT WITHOUT DISSOLVED COMPANIES
q1 = f"""
select ?country ?company (count(*) as ?owned) where{{
# ?company wdt:P31 wd:Q4830453 ;
    wdt:P1830 ?anotherCompany ;
    wdt:P17 ?country .
# ?anotherCompany wdt:P31 wd:Q4830453 ;
    wdt:P17 ?anotherCountry .
    
filter(?country != ?anotherCountry) .
}}
group by ?country ?company
"""
#having q1, select for each returned country the greates amount of businesses owned in other countries across all companies
q2 = f"""
select ?country (max(?owned) as ?max) where{{

    {{
        select ?country ?company (count(*) as ?owned) where{{

# ?company wdt:P31 wd:Q4830453 ;

    wdt:P1830 ?anotherCompany ;

    wdt:P17 ?country .

# ?anotherCompany wdt:P31 wd:Q4830453 ;

    wdt:P17 ?anotherCountry .

    

filter(?country != ?anotherCountry) .

}}

group by ?country ?company



    }}
}}
group by ?country
"""
#this is a repeat of q1, with different names for the variables
q3 = f"""
select ?c ?ct (count(*) as ?tot) where{{
# ?c wdt:P31 wd:Q4830453 ;
    wdt:P1830 ?anotherCompany ;
    wdt:P17 ?ct .
# ?anotherCompany wdt:P31 wd:Q4830453 ;
    wdt:P17 ?anotherCountry .
    
filter(?ct != ?anotherCountry) .
}}
group by ?c ?ct
"""

#having for each country the greatest number of businesses from another country that a certain local business owns select ?country (max(?owned) as ?max) where{{



    {{

        select ?country ?company (count(*) as ?owned) where{{

# ?company wdt:P31 wd:Q4830453 ;

    wdt:P1830 ?anotherCompany ;

    wdt:P17 ?country .

# ?anotherCompany wdt:P31 wd:Q4830453 ;

    wdt:P17 ?anotherCountry .

    

filter(?country != ?anotherCountry) .

}}

group by ?country ?company




    }}

}}

group by ?country



#and having the list of each business and the number of non local businesses it owns, along with its original country select ?c ?ct (count(*) as ?tot) where{{

# ?c wdt:P31 wd:Q4830453 ;

    wdt:P1830 ?anotherCompany ;

    wdt:P17 ?ct .

# ?anotherCompany wdt:P31 wd:Q4830453 ;

    wdt:P17 ?anotherCountry .

    

filter(?ct != ?anotherCountry) .

}}

group by ?c ?ct



#we simply compare country and count in the 2 sets, when they match we return the corresponding business
q4 = f"""
select ?countryName ?companyName ?max where{{
# ?c <http://schema.org/name> ?companyName .
# ?country <http://schema.org/name> ?countryName .
    {{
        select ?c ?ct (count(*) as ?tot) where{{

# ?c wdt:P31 wd:Q4830453 ;

    wdt:P1830 ?anotherCompany ;

    wdt:P17 ?ct .

# ?anotherCompany wdt:P31 wd:Q4830453 ;

    wdt:P17 ?anotherCountry .

    

filter(?ct != ?anotherCountry) .

}}

group by ?c ?ct



    }}
    
    {{
        select ?country (max(?owned) as ?max) where{{



    {{

        select ?country ?company (count(*) as ?owned) where{{

# ?company wdt:P31 wd:Q4830453 ;

    wdt:P1830 ?anotherCompany ;

    wdt:P17 ?country .

# ?anotherCompany wdt:P31 wd:Q4830453 ;

    wdt:P17 ?anotherCountry .

    

filter(?country != ?anotherCountry) .

}}

group by ?country ?company




    }}

}}

group by ?country



    }}
filter(?tot = ?max && ?ct = ?country) .
filter not exists {{

        # ?c wdt:P576 ?dissolution .
    }}
}}
"""
run_query(q4)
# Out:
# [('countryName', 'Union of South Africa'), ('companyName', 'Union Corporation'), ('max', '1')]
# [('countryName', 'France'), ('companyName', 'LVMH'), ('max', '10')]
# [('countryName', 'United Kingdom'), ('companyName', 'Tesco'), ('max', '8')]
# [('countryName', "People's Republic of China"), ('companyName', 'Alibaba Group'), ('max', '3')]
# [('countryName', 'Brazil'), ('companyName', 'Anheuser-Busch InBev'), ('max', '9')]
# [('countryName', 'Russia'), ('companyName', 'Sberbank of Russia'), ('max', '2')]
# [('countryName', 'Russia'), ('companyName', 'Basic Element'), ('max', '2')]
# [('countryName', 'Canada'), ('companyName', 'Corel'), ('max', '3')]
# [('countryName', 'Japan'), ('companyName', 'Sony'), ('max', '10')]
# [('countryName', 'United Kingdom of Great Britain and Ireland'), ('companyName', 'Brazilian Warrant Agency and Finance Co'), ('max', '1')]
# [('countryName', 'Germany'), ('companyName', 'Aachen Münchener'), ('max', '7')]
# [('countryName', 'Estonia'), ('companyName', 'Luminor Bank'), ('max', '1')]
# [('countryName', 'Norway'), ('companyName', 'Telenor'), ('max', '6')]
# [('countryName', 'Ukraine'), ('companyName', 'Naftogaz'), ('max', '1')]
# [('countryName', 'Czech Republic'), ('companyName', 'Škoda Auto'), ('max', '3')]
# [('countryName', 'Czech Republic'), ('companyName', 'EP Infrastructure'), ('max', '3')]
# [('countryName', 'Czech Republic'), ('companyName', 'EP Power Europe'), ('max', '3')]
# [('countryName', 'Slovakia'), ('companyName', 'DOAS SK'), ('max', '2')]
# [('countryName', 'Slovakia'), ('companyName', 'Tatry Mountain Resorts'), ('max', '2')]
# [('countryName', 'Slovakia'), ('companyName', 'Supernius'), ('max', '2')]
# [('countryName', 'Romania'), ('companyName', 'Citibank'), ('max', '1')]
# [('countryName', 'Croatia'), ('companyName', 'Agrokor'), ('max', '3')]
# [('countryName', 'Cyprus'), ('companyName', 'Penta Investments Limited'), ('max', '4')]
# [('countryName', 'Malta'), ('companyName', 'Priveq Funds'), ('max', '2')]
# [('countryName', 'Bermuda'), ('companyName', 'ACP Partners Limited'), ('max', '1')]
# [('countryName', 'Guernsey'), ('companyName', 'Buteo Rapax'), ('max', '1')]
# [('countryName', 'Guernsey'), ('companyName', 'Pratincole Investments'), ('max', '1')]
# [('countryName', 'Guernsey'), ('companyName', 'Macquarie European Infrastructure Fund II'), ('max', '1')]
# [('countryName', 'Guernsey'), ('companyName', 'Genesis Private Equity Fund III'), ('max', '1')]
# [('countryName', 'British Virgin Islands'), ('companyName', 'White Surrey'), ('max', '1')]
# [('countryName', 'British Virgin Islands'), ('companyName', 'Euro Capital Alliance'), ('max', '1')]
# [('countryName', 'British Virgin Islands'), ('companyName', 'China United Association International Funding Centre'), ('max', '1')]
# [('countryName', 'British Virgin Islands'), ('companyName', 'Hengxin Enterprises'), ('max', '1')]
# [('countryName', 'British Virgin Islands'), ('companyName', 'USM Holdings'), ('max', '1')]
# [('countryName', 'British Virgin Islands'), ('companyName', 'Eridanus Investments'), ('max', '1')]
# [('countryName', 'British Virgin Islands'), ('companyName', 'Orozco Holdings'), ('max', '1')]
# [('countryName', 'British Virgin Islands'), ('companyName', 'Lilyvale Limited'), ('max', '1')]
# [('countryName', 'British Virgin Islands'), ('companyName', 'BXR Group Limited'), ('max', '1')]
# [('countryName', 'British Virgin Islands'), ('companyName', 'Vixon Resources'), ('max', '1')]
# [('countryName', 'British Virgin Islands'), ('companyName', 'Chelton Properties'), ('max', '1')]
# [('countryName', 'South Africa'), ('companyName', 'De Beers'), ('max', '1')]
# [('countryName', 'Algeria'), ('companyName', 'Cevital'), ('max', '2')]
# [('countryName', 'Ireland'), ('companyName', 'Accenture'), ('max', '1')]
# [('countryName', 'Ireland'), ('companyName', 'Facebook International Operations Limited'), ('max', '1')]
# [('countryName', 'Ireland'), ('companyName', 'Gosford Capital Designated Activity Company'), ('max', '1')]
# [('countryName', 'Hungary'), ('companyName', 'Cloud Network Technology'), ('max', '2')]
# [('countryName', 'Spain'), ('companyName', 'Telefónica'), ('max', '5')]
# [('countryName', 'Kingdom of the Netherlands'), ('companyName', 'CZI Holdings'), ('max', '2')]
# [('countryName', 'United States of America'), ('companyName', 'The Walt Disney Company'), ('max', '6')]
# [('countryName', 'United States of America'), ('companyName', 'Ford Motor Company'), ('max', '6')]
# [('countryName', 'Belgium'), ('companyName', 'Anheuser-Busch InBev'), ('max', '9')]
# [('countryName', 'Luxembourg'), ('companyName', 'NexGen'), ('max', '13')]
# [('countryName', 'Finland'), ('companyName', 'Amer Sports'), ('max', '5')]
# [('countryName', 'Singapore'), ('companyName', 'GIC Private Limited'), ('max', '3')]
# [('countryName', 'Sweden'), ('companyName', 'Electrolux'), ('max', '5')]
# [('countryName', 'Liechtenstein'), ('companyName', 'Nemo Fund'), ('max', '3')]
# [('countryName', 'Denmark'), ('companyName', 'Carlsberg Group'), ('max', '10')]
# [('countryName', 'Poland'), ('companyName', 'PKN Orlen'), ('max', '1')]
# [('countryName', 'Poland'), ('companyName', 'PKP Cargo'), ('max', '1')]
# [('countryName', 'Italy'), ('companyName', 'Lavazza'), ('max', '4')]
# [('countryName', 'Switzerland'), ('companyName', 'Richemont'), ('max', '4')]
# [('countryName', 'Austria'), ('companyName', 'A1 Telekom Austria Group'), ('max', '2')]
# [('countryName', 'Austria'), ('companyName', 'Benteler International'), ('max', '2')]
# [('countryName', 'Austria'), ('companyName', 'Strabag Holding'), ('max', '2')]
# [('countryName', 'Australia'), ('companyName', 'BHP Group'), ('max', '1')]
# [('countryName', 'Turkey'), ('companyName', 'Yamaha Corporation'), ('max', '4')]
# [('countryName', 'Netherlands'), ('companyName', 'Heineken'), ('max', '10')]
# [('countryName', 'Cayman Islands'), ('companyName', 'Manchester United Plc'), ('max', '1')]
# [('countryName', 'Cayman Islands'), ('companyName', 'CZ Investments'), ('max', '1')]
# [('countryName', 'Cayman Islands'), ('companyName', 'Tritton Development Fund'), ('max', '1')]
# [('countryName', 'Cayman Islands'), ('companyName', 'BTO Ripple Holdings'), ('max', '1')]
# [('countryName', 'Cayman Islands'), ('companyName', 'BT Global Investments'), ('max', '1')]
# [('countryName', 'Cayman Islands'), ('companyName', 'Chorus Explorers Fund I SPC'), ('max', '1')]
# [('countryName', 'India'), ('companyName', 'Tata Motors'), ('max', '1')]
# [('countryName', 'Marshall Islands'), ('companyName', 'Maranex Finance'), ('max', '1')]
# [('countryName', 'The Bahamas'), ('companyName', 'Camron Investment Management'), ('max', '1')]
# [('countryName', 'Jersey'), ('companyName', 'Penta Investments Limited'), ('max', '7')]
# [('countryName', 'Israel'), ('companyName', 'Bezeq'), ('max', '1')]
# [('countryName', 'Lebanon'), ('companyName', 'Globe Re Sal'), ('max', '1')]
# [('countryName', 'Malaysia'), ('companyName', 'Axiata'), ('max', '3')]
# [('countryName', 'Hong Kong'), ('companyName', 'China International Group Corporation'), ('max', '3')]
# [('countryName', 'Taiwan'), ('companyName', 'Acer Inc.'), ('max', '2')]
# [('countryName', 'Thailand'), ('companyName', 'Charoen Pokphand'), ('max', '1')]
# [('countryName', 'United Arab Emirates'), ('companyName', 'Emirates Telecommunications Corporation'), ('max', '2')]
# [('countryName', 'Mexico'), ('companyName', 'América Móvil'), ('max', '2')]
# 85

# %%
#get for each country: business and how many businesses it owns in other countries
#REPEAT WITHOUT DISSOLVED COMPANIES
#LIMITED TO CANADA, UK, US
q1 = f"""
select ?country ?company (count(*) as ?owned) where{{
# ?company wdt:P31 wd:Q4830453 ;
    wdt:P1830 ?anotherCompany ;
    wdt:P17 ?country .
# ?anotherCompany wdt:P31 wd:Q4830453 ;
    wdt:P17 ?anotherCountry .
    
filter(?country != ?anotherCountry) .
}}
group by ?country ?company
"""
#having q1, select for each returned country the greates amount of businesses owned in other countries across all companies
q2 = f"""
select ?country (max(?owned) as ?max) where{{

    {{
        select ?country ?company (count(*) as ?owned) where{{

# ?company wdt:P31 wd:Q4830453 ;

    wdt:P1830 ?anotherCompany ;

    wdt:P17 ?country .

# ?anotherCompany wdt:P31 wd:Q4830453 ;

    wdt:P17 ?anotherCountry .

    

filter(?country != ?anotherCountry) .

}}

group by ?country ?company



    }}
}}
group by ?country
"""
#this is a repeat of q1, with different names for the variables
q3 = f"""
select ?c ?ct (count(*) as ?tot) where{{
# ?c wdt:P31 wd:Q4830453 ;
    wdt:P1830 ?anotherCompany ;
    wdt:P17 ?ct .
# ?anotherCompany wdt:P31 wd:Q4830453 ;
    wdt:P17 ?anotherCountry .
    
filter(?ct != ?anotherCountry) .
}}
group by ?c ?ct
"""

#having for each country the greatest number of businesses from another country that a certain local business owns select ?country (max(?owned) as ?max) where{{



    {{

        select ?country ?company (count(*) as ?owned) where{{

# ?company wdt:P31 wd:Q4830453 ;

    wdt:P1830 ?anotherCompany ;

    wdt:P17 ?country .

# ?anotherCompany wdt:P31 wd:Q4830453 ;

    wdt:P17 ?anotherCountry .

    

filter(?country != ?anotherCountry) .

}}

group by ?country ?company




    }}

}}

group by ?country



#and having the list of each business and the number of non local businesses it owns, along with its original country select ?c ?ct (count(*) as ?tot) where{{

# ?c wdt:P31 wd:Q4830453 ;

    wdt:P1830 ?anotherCompany ;

    wdt:P17 ?ct .

# ?anotherCompany wdt:P31 wd:Q4830453 ;

    wdt:P17 ?anotherCountry .

    

filter(?ct != ?anotherCountry) .

}}

group by ?c ?ct



#we simply compare country and count in the 2 sets, when they match we return the corresponding business
q4 = f"""
select ?countryName ?companyName ?max where{{
# ?c <http://schema.org/name> ?companyName .
# ?country <http://schema.org/name> ?countryName .
filter(?country in (wd:Q16, wd:Q145, wd:Q30))
    {{
        select ?c ?ct (count(*) as ?tot) where{{

# ?c wdt:P31 wd:Q4830453 ;

    wdt:P1830 ?anotherCompany ;

    wdt:P17 ?ct .

# ?anotherCompany wdt:P31 wd:Q4830453 ;

    wdt:P17 ?anotherCountry .

    

filter(?ct != ?anotherCountry) .

}}

group by ?c ?ct



    }}
    
    {{
        select ?country (max(?owned) as ?max) where{{



    {{

        select ?country ?company (count(*) as ?owned) where{{

# ?company wdt:P31 wd:Q4830453 ;

    wdt:P1830 ?anotherCompany ;

    wdt:P17 ?country .

# ?anotherCompany wdt:P31 wd:Q4830453 ;

    wdt:P17 ?anotherCountry .

    

filter(?country != ?anotherCountry) .

}}

group by ?country ?company




    }}

}}

group by ?country



    }}
filter(?tot = ?max && ?ct = ?country) .
filter not exists {{

        # ?c wdt:P576 ?dissolution .
    }}
}}
"""
run_query(q4)
# Out:
# [('countryName', 'United States of America'), ('companyName', 'The Walt Disney Company'), ('max', '6')]
# [('countryName', 'Canada'), ('companyName', 'Corel'), ('max', '3')]
# [('countryName', 'United States of America'), ('companyName', 'Ford Motor Company'), ('max', '6')]
# [('countryName', 'United Kingdom'), ('companyName', 'Tesco'), ('max', '8')]
# 4

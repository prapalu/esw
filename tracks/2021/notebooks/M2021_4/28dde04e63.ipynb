# %% [markdown]
# # General instructions
#
# The goal of the project is to materialize a set of **exploratory workloads** over a real-world, large-scale,  open-domain KG: [WikiData](https://www.wikidata.org/wiki/Wikidata:Main_Page)
#
# An exploratory workload  is composed by a set of queries, where each query is related to the information obtained previously.
#
# An exploratory workload starts with a usually vague, open ended question, and does not assume the person issuing the workload has a clear understanding of the data contained in the target database or its structure.
#
# Remeber that:
#
# 1. All the queries must run in the python notebook
# 2. You can use classes and properties only if you find them via a SPARQL query that must be present in the notebook
# 3. You do not delete useless queries. Keep everything that is synthatically valid
#
# ```
# ?p <http://schema.org/name> ?name .
# ```
#
#     is the BGP returning a human-readable name of a property or a class in Wikidata.

# %%
## SETUP used later

from SPARQLWrapper import SPARQLWrapper, JSON


prefixString = """
##-28dde04e63-##
PREFIX wd: <http://www.wikidata.org/entity/> 
PREFIX wdt: <http://www.wikidata.org/prop/direct/> 
PREFIX sc: <http://schema.org/>
"""

# select and construct queries
def run_query(queryString):
    to_run = prefixString + "\n" + queryString

    sparql = SPARQLWrapper("http://a256-gc1-02.srv.aau.dk:5820/sparql")
    sparql.setTimeout(300)
    sparql.setReturnFormat(JSON)
    sparql.setQuery(to_run)

    try :
       results = sparql.query()
       json_results = results.convert()
       if len(json_results['results']['bindings'])==0:
          print("Empty")
          return 0
    
       for bindings in json_results['results']['bindings']:
          print( [ (var, value['value'])  for var, value in bindings.items() ] )

       return len(json_results['results']['bindings'])

    except Exception as e :
        print("The operation failed", e)
    
# ASk queries
def run_ask_query(queryString):
    to_run = prefixString + "\n" + queryString

    sparql = SPARQLWrapper("http://a256-gc1-03.srv.aau.dk:5820/sparql")
    sparql.setTimeout(300)
    sparql.setReturnFormat(JSON)
    sparql.setQuery(to_run)

    try :
        return sparql.query().convert()

    except Exception as e :
        print("The operation failed", e)

# %% [markdown]
# # Movie Workflow Series ("Horror Franchises explorative search")
#
# Consider the following exploratory scenario:
#
#
# > we are interested in horror movies, in particular we care about the slasher subgenre, and we want to compare the Halloween and the Friday the 13th francise.
#
# Background knowledge useful for better conducting the search: Halloween is a movie from 1978 with many sequels and the set of Halloween + all the sequels is called the "Halloween franchise". The same considerations hold for Friday the 13th.
#
#
# ## Useful URIs for the current workflow
# The following are given:
#
# | IRI           | Description   | Role      |
# | -----------   | -----------   |-----------|
# | `wdt:P1647`   | subproperty   | predicate |
# | `wdt:P31`     | instance of   | predicate |
# | `wdt:P106`    | profession    | predicate |
# | `wdt:P279`    | subclass      | predicate |
# | `wd:Q221103`     | Halloween       | node |
# | `wd:Q1243029`| Friday the 13th       | node |
#
#
#
#
#
# Also consider
#
# ```
# wd:Q1243029 ?p ?obj .
# ```
#
# is the BGP to retrieve all **properties of Friday the 13th**
#
# The workload should
#
#
# 1. Investigate the workers of the two original movies and check any commonality
#
# 2. Check who was the most famous actor/actress on Halloween and Friday the 13th at the time of the release (e.g., the actor/actress who acted in more movies before and/or the actor/actress who won more academy awards)
#
# 3. Check which actor/actress did more movies after the release of these two films (consider the films separately)
#
# 4. Get all the movies of the two franchises (return year and director)
#
# 5. Who is most involved in a franchise (who did something in the movies, e.g., writer, director, producer)?
#
# 6. Investigate which franchise is highly regarded by the critics overall
#
# 7. Investigate which franchise costed more

# %% [markdown]
# ### Task 1

# %%
# start your workflow here

# %%
queryString = """
SELECT *
WHERE { 

wd:Q1243029 ?p ?obj .
} 
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('p', 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), ('obj', 'http://wikiba.se/ontology#Item')]
# [('p', 'http://www.wikidata.org/prop/direct-normalized/P244'), ('obj', 'https://id.loc.gov/authorities/names/no98033420')]
# [('p', 'http://www.wikidata.org/prop/direct-normalized/P3212'), ('obj', 'urn:isan:0000-0000-31EA-0000-G-0000-0000-Q')]
# [('p', 'http://www.wikidata.org/prop/direct-normalized/P4276'), ('obj', 'https://data.cinematheque.qc.ca/data/Work1467')]
# [('p', 'http://www.wikidata.org/prop/direct-normalized/P646'), ('obj', 'http://g.co/kg/m/016mng')]
# [('p', 'http://www.wikidata.org/prop/direct/P1237'), ('obj', 'friday13th')]
# [('p', 'http://www.wikidata.org/prop/direct/P1258'), ('obj', 'm/friday_the_13th_part_1')]
# [('p', 'http://www.wikidata.org/prop/direct/P1265'), ('obj', '505')]
# [('p', 'http://www.wikidata.org/prop/direct/P136'), ('obj', 'http://www.wikidata.org/entity/Q1067324')]
# [('p', 'http://www.wikidata.org/prop/direct/P136'), ('obj', 'http://www.wikidata.org/entity/Q1200678')]
# [('p', 'http://www.wikidata.org/prop/direct/P136'), ('obj', 'http://www.wikidata.org/entity/Q853630')]
# [('p', 'http://www.wikidata.org/prop/direct/P136'), ('obj', 'http://www.wikidata.org/entity/Q909586')]
# [('p', 'http://www.wikidata.org/prop/direct/P1411'), ('obj', 'http://www.wikidata.org/entity/Q1780634')]
# [('p', 'http://www.wikidata.org/prop/direct/P1411'), ('obj', 'http://www.wikidata.org/entity/Q977915')]
# [('p', 'http://www.wikidata.org/prop/direct/P1476'), ('obj', 'Friday the 13th')]
# [('p', 'http://www.wikidata.org/prop/direct/P156'), ('obj', 'http://www.wikidata.org/entity/Q1243009')]
# [('p', 'http://www.wikidata.org/prop/direct/P1562'), ('obj', 'v18658')]
# [('p', 'http://www.wikidata.org/prop/direct/P161'), ('obj', 'http://www.wikidata.org/entity/Q2440012')]
# [('p', 'http://www.wikidata.org/prop/direct/P161'), ('obj', 'http://www.wikidata.org/entity/Q263765')]
# [('p', 'http://www.wikidata.org/prop/direct/P161'), ('obj', 'http://www.wikidata.org/entity/Q3428829')]
# [('p', 'http://www.wikidata.org/prop/direct/P161'), ('obj', 'http://www.wikidata.org/entity/Q3434272')]
# [('p', 'http://www.wikidata.org/prop/direct/P161'), ('obj', 'http://www.wikidata.org/entity/Q3454165')]
# [('p', 'http://www.wikidata.org/prop/direct/P161'), ('obj', 'http://www.wikidata.org/entity/Q13218111')]
# [('p', 'http://www.wikidata.org/prop/direct/P161'), ('obj', 'http://www.wikidata.org/entity/Q2570201')]
# [('p', 'http://www.wikidata.org/prop/direct/P161'), ('obj', 'http://www.wikidata.org/entity/Q3047636')]
# [('p', 'http://www.wikidata.org/prop/direct/P161'), ('obj', 'http://www.wikidata.org/entity/Q524486')]
# [('p', 'http://www.wikidata.org/prop/direct/P162'), ('obj', 'http://www.wikidata.org/entity/Q709325')]
# [('p', 'http://www.wikidata.org/prop/direct/P1712'), ('obj', 'movie/friday-the-13th-1980')]
# [('p', 'http://www.wikidata.org/prop/direct/P175'), ('obj', 'http://www.wikidata.org/entity/Q664025')]
# [('p', 'http://www.wikidata.org/prop/direct/P179'), ('obj', 'http://www.wikidata.org/entity/Q1138878')]
# [('p', 'http://www.wikidata.org/prop/direct/P18'), ('obj', 'http://commons.wikimedia.org/wiki/Special:FilePath/Friday%20the%2013th%20%281980%29%20film%20logo.png')]
# [('p', 'http://www.wikidata.org/prop/direct/P1804'), ('obj', '1319')]
# [('p', 'http://www.wikidata.org/prop/direct/P1874'), ('obj', '525111')]
# [('p', 'http://www.wikidata.org/prop/direct/P1889'), ('obj', 'http://www.wikidata.org/entity/Q1454815')]
# [('p', 'http://www.wikidata.org/prop/direct/P1970'), ('obj', '1191')]
# [('p', 'http://www.wikidata.org/prop/direct/P2047'), ('obj', '91')]
# [('p', 'http://www.wikidata.org/prop/direct/P2061'), ('obj', 'http://www.wikidata.org/entity/Q752245')]
# [('p', 'http://www.wikidata.org/prop/direct/P2334'), ('obj', '7782')]
# [('p', 'http://www.wikidata.org/prop/direct/P2346'), ('obj', '133662')]
# [('p', 'http://www.wikidata.org/prop/direct/P244'), ('obj', 'no98033420')]
# [('p', 'http://www.wikidata.org/prop/direct/P2465'), ('obj', '10511')]
# [('p', 'http://www.wikidata.org/prop/direct/P2508'), ('obj', '4386')]
# [('p', 'http://www.wikidata.org/prop/direct/P2509'), ('obj', 'mv4378')]
# [('p', 'http://www.wikidata.org/prop/direct/P2518'), ('obj', '1265')]
# [('p', 'http://www.wikidata.org/prop/direct/P2529'), ('obj', '23053')]
# [('p', 'http://www.wikidata.org/prop/direct/P2603'), ('obj', '23922')]
# [('p', 'http://www.wikidata.org/prop/direct/P2631'), ('obj', '17974')]
# [('p', 'http://www.wikidata.org/prop/direct/P2638'), ('obj', 'movies/friday-the-13th-1980')]
# [('p', 'http://www.wikidata.org/prop/direct/P2704'), ('obj', '10.5240/7544-6FCA-F299-ECD8-BE4D-A')]
# [('p', 'http://www.wikidata.org/prop/direct/P272'), ('obj', 'http://www.wikidata.org/entity/Q159846')]
# [('p', 'http://www.wikidata.org/prop/direct/P2747'), ('obj', 'http://www.wikidata.org/entity/Q23830579')]
# [('p', 'http://www.wikidata.org/prop/direct/P2755'), ('obj', '52986')]
# [('p', 'http://www.wikidata.org/prop/direct/P2758'), ('obj', 'http://www.wikidata.org/entity/Q23817741')]
# [('p', 'http://www.wikidata.org/prop/direct/P3077'), ('obj', '18183')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('obj', 'http://www.wikidata.org/entity/Q11424')]
# [('p', 'http://www.wikidata.org/prop/direct/P3107'), ('obj', '25470')]
# [('p', 'http://www.wikidata.org/prop/direct/P3129'), ('obj', '651006')]
# [('p', 'http://www.wikidata.org/prop/direct/P3138'), ('obj', '53')]
# [('p', 'http://www.wikidata.org/prop/direct/P3141'), ('obj', 't0003232')]
# [('p', 'http://www.wikidata.org/prop/direct/P3143'), ('obj', '80561')]
# [('p', 'http://www.wikidata.org/prop/direct/P3203'), ('obj', '54093')]
# [('p', 'http://www.wikidata.org/prop/direct/P3212'), ('obj', '0000-0000-31EA-0000-G-0000-0000-Q')]
# [('p', 'http://www.wikidata.org/prop/direct/P3302'), ('obj', '4488')]
# [('p', 'http://www.wikidata.org/prop/direct/P344'), ('obj', 'http://www.wikidata.org/entity/Q4863956')]
# [('p', 'http://www.wikidata.org/prop/direct/P345'), ('obj', 'tt0080761')]
# [('p', 'http://www.wikidata.org/prop/direct/P3593'), ('obj', '56417')]
# [('p', 'http://www.wikidata.org/prop/direct/P364'), ('obj', 'http://www.wikidata.org/entity/Q1860')]
# [('p', 'http://www.wikidata.org/prop/direct/P3804'), ('obj', '123800')]
# [('p', 'http://www.wikidata.org/prop/direct/P3808'), ('obj', 'Friday-the-13th')]
# [('p', 'http://www.wikidata.org/prop/direct/P3844'), ('obj', '1142')]
# [('p', 'http://www.wikidata.org/prop/direct/P3933'), ('obj', '1294128')]
# [('p', 'http://www.wikidata.org/prop/direct/P4276'), ('obj', '1467')]
# [('p', 'http://www.wikidata.org/prop/direct/P4282'), ('obj', '13638')]
# [('p', 'http://www.wikidata.org/prop/direct/P437'), ('obj', 'http://www.wikidata.org/entity/Q723685')]
# [('p', 'http://www.wikidata.org/prop/direct/P4529'), ('obj', '1293143')]
# [('p', 'http://www.wikidata.org/prop/direct/P462'), ('obj', 'http://www.wikidata.org/entity/Q22006653')]
# [('p', 'http://www.wikidata.org/prop/direct/P4632'), ('obj', '4569')]
# [('p', 'http://www.wikidata.org/prop/direct/P4665'), ('obj', '6056')]
# [('p', 'http://www.wikidata.org/prop/direct/P480'), ('obj', '265349')]
# [('p', 'http://www.wikidata.org/prop/direct/P4947'), ('obj', '4488')]
# [('p', 'http://www.wikidata.org/prop/direct/P495'), ('obj', 'http://www.wikidata.org/entity/Q30')]
# [('p', 'http://www.wikidata.org/prop/direct/P4969'), ('obj', 'http://www.wikidata.org/entity/Q1454815')]
# [('p', 'http://www.wikidata.org/prop/direct/P5021'), ('obj', 'http://www.wikidata.org/entity/Q4165246')]
# [('p', 'http://www.wikidata.org/prop/direct/P5032'), ('obj', '8684')]
# [('p', 'http://www.wikidata.org/prop/direct/P5099'), ('obj', 'film/venerdi13')]
# [('p', 'http://www.wikidata.org/prop/direct/P5693'), ('obj', '93065')]
# [('p', 'http://www.wikidata.org/prop/direct/P57'), ('obj', 'http://www.wikidata.org/entity/Q709325')]
# [('p', 'http://www.wikidata.org/prop/direct/P577'), ('obj', '1980-05-09T00:00:00Z')]
# [('p', 'http://www.wikidata.org/prop/direct/P577'), ('obj', '1980-10-23T00:00:00Z')]
# [('p', 'http://www.wikidata.org/prop/direct/P577'), ('obj', '1980-11-10T00:00:00Z')]
# [('p', 'http://www.wikidata.org/prop/direct/P5786'), ('obj', 'freitag-der-13')]
# [('p', 'http://www.wikidata.org/prop/direct/P58'), ('obj', 'http://www.wikidata.org/entity/Q7926158')]
# [('p', 'http://www.wikidata.org/prop/direct/P5905'), ('obj', '4025-275')]
# [('p', 'http://www.wikidata.org/prop/direct/P6127'), ('obj', 'friday-the-13th')]
# [('p', 'http://www.wikidata.org/prop/direct/P6262'), ('obj', 'movies:Friday_the_13th_(1980)')]
# [('p', 'http://www.wikidata.org/prop/direct/P6262'), ('obj', 'the80smovies:Friday_the_13th')]
# [('p', 'http://www.wikidata.org/prop/direct/P6398'), ('obj', '305332580')]
# [('p', 'http://www.wikidata.org/prop/direct/P6398'), ('obj', '312028305')]
# [('p', 'http://www.wikidata.org/prop/direct/P646'), ('obj', '/m/016mng')]
# [('p', 'http://www.wikidata.org/prop/direct/P6562'), ('obj', '-er1PNqRLiI')]
# [('p', 'http://www.wikidata.org/prop/direct/P674'), ('obj', 'http://www.wikidata.org/entity/Q2576457')]
# [('p', 'http://www.wikidata.org/prop/direct/P674'), ('obj', 'http://www.wikidata.org/entity/Q366957')]
# [('p', 'http://www.wikidata.org/prop/direct/P750'), ('obj', 'http://www.wikidata.org/entity/Q80948336')]
# [('p', 'http://www.wikidata.org/prop/direct/P750'), ('obj', 'http://www.wikidata.org/entity/Q907311')]
# [('p', 'http://www.wikidata.org/prop/direct/P750'), ('obj', 'http://www.wikidata.org/entity/Q159846')]
# [('p', 'http://www.wikidata.org/prop/direct/P7970'), ('obj', '1MV59a10bc8835dfb67d1a4a2bf5428a03b')]
# [('p', 'http://www.wikidata.org/prop/direct/P8033'), ('obj', 'friday-the-13th-m100051176')]
# [('p', 'http://www.wikidata.org/prop/direct/P840'), ('obj', 'http://www.wikidata.org/entity/Q1408')]
# [('p', 'http://www.wikidata.org/prop/direct/P856'), ('obj', 'http://www.fridaythe13thfilms.com')]
# [('p', 'http://www.wikidata.org/prop/direct/P86'), ('obj', 'http://www.wikidata.org/entity/Q664025')]
# [('p', 'http://www.wikidata.org/prop/direct/P905'), ('obj', '7021')]
# [('p', 'http://www.wikidata.org/prop/direct/P915'), ('obj', 'http://www.wikidata.org/entity/Q1408')]
# [('p', 'http://www.wikidata.org/prop/direct/P9586'), ('obj', 'umc.cmc.4cny06c1e312h2mfd2utrtve2')]
# [('p', 'http://schema.org/name'), ('obj', 'Friday the 13th')]
# [('p', 'http://www.wikidata.org/prop/direct/P2554'), ('obj', 'http://www.wikidata.org/entity/Q450964')]
# [('p', 'http://www.wikidata.org/prop/direct/P4277'), ('obj', '10178')]
# [('p', 'http://www.wikidata.org/prop/direct/P7975'), ('obj', '1283')]
# [('p', 'http://www.wikidata.org/prop/direct/P6466'), ('obj', '98dc6b45-4478-4877-8316-acc3c7f6ae94')]
# 118

# %%
# Return all properties outgoing from Halloween film
queryString = """
SELECT DISTINCT ?property ?propertyName
WHERE { 

    wd:Q221103 ?property ?object.
    # ?property <http://schema.org/name> ?propertyName.
} 
ORDER BY ?propertyName
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('property', 'http://www.wikidata.org/prop/direct/P3593'), ('propertyName', 'AFI Catalog of Feature Films ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1562'), ('propertyName', 'AllMovie title ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2465'), ('propertyName', 'Allcinema film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1265'), ('propertyName', 'AlloCiné film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P9586'), ('propertyName', 'Apple TV movie ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4632'), ('propertyName', 'Bechdel Test Movie List ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1237'), ('propertyName', 'Box Office Mojo film ID (former scheme)')]
# [('property', 'http://www.wikidata.org/prop/direct/P4665'), ('propertyName', 'CineMagia title ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3933'), ('propertyName', 'Cinema.de ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3077'), ('propertyName', 'Cineplex Germany film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4276'), ('propertyName', 'Cinémathèque québécoise work identifier')]
# [('property', 'http://www.wikidata.org/prop/direct/P5905'), ('propertyName', 'Comic Vine ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1804'), ('propertyName', 'DNF film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4277'), ('propertyName', 'Daum movie ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3844'), ('propertyName', 'Deutsche Synchronkartei film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4529'), ('propertyName', 'Douban film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3141'), ('propertyName', 'EDb film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2704'), ('propertyName', 'EIDR content ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2346'), ('propertyName', 'Elonet movie ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1417'), ('propertyName', 'Encyclopædia Britannica Online ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6262'), ('propertyName', 'Fandom article ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P480'), ('propertyName', 'FilmAffinity ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7975'), ('propertyName', 'Filmfront film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2747'), ('propertyName', 'Filmiroda rating')]
# [('property', 'http://www.wikidata.org/prop/direct/P5032'), ('propertyName', 'Filmweb.pl film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P646'), ('propertyName', 'Freebase ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P227'), ('propertyName', 'GND ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P345'), ('propertyName', 'IMDb ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3212'), ('propertyName', 'ISAN')]
# [('property', 'http://www.wikidata.org/prop/direct/P5099'), ('propertyName', 'Il mondo dei doppiatori ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2508'), ('propertyName', 'KINENOTE film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2603'), ('propertyName', 'Kinopoisk film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4282'), ('propertyName', 'LUMIERE film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6058'), ('propertyName', 'Larousse ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3107'), ('propertyName', 'LdiF ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6127'), ('propertyName', 'Letterboxd film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P244'), ('propertyName', 'Library of Congress authority ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4780'), ('propertyName', 'MYmovies movie ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5970'), ('propertyName', 'Medierådet rating')]
# [('property', 'http://www.wikidata.org/prop/direct/P1712'), ('propertyName', 'Metacritic ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P8033'), ('propertyName', 'Movie Review Query Engine ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2509'), ('propertyName', 'Movie Walker film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1970'), ('propertyName', 'MovieMeter film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5786'), ('propertyName', 'Moviepilot.de film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1874'), ('propertyName', 'Netflix ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3138'), ('propertyName', 'OFDb film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3302'), ('propertyName', 'Open Media Database film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P905'), ('propertyName', 'PORT film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1258'), ('propertyName', 'Rotten Tomatoes ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2518'), ('propertyName', 'Scope.dk film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2334'), ('propertyName', 'Swedish Film Database film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2631'), ('propertyName', 'TCM Movie Database film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4947'), ('propertyName', 'TMDb movie ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3804'), ('propertyName', 'TV Guide show ID (former scheme)')]
# [('property', 'http://www.wikidata.org/prop/direct/P2638'), ('propertyName', 'TV.com ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3808'), ('propertyName', 'The Numbers movie ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P214'), ('propertyName', 'VIAF ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7334'), ('propertyName', 'Vudu video ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2061'), ('propertyName', 'aspect ratio')]
# [('property', 'http://www.wikidata.org/prop/direct/P5021'), ('propertyName', 'assessment')]
# [('property', 'http://www.wikidata.org/prop/direct/P166'), ('propertyName', 'award received')]
# [('property', 'http://www.wikidata.org/prop/direct/P161'), ('propertyName', 'cast member')]
# [('property', 'http://www.wikidata.org/prop/direct/P3129'), ('propertyName', 'cine.gr film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P462'), ('propertyName', 'color')]
# [('property', 'http://www.wikidata.org/prop/direct/P86'), ('propertyName', 'composer')]
# [('property', 'http://www.wikidata.org/prop/direct/P2130'), ('propertyName', 'cost')]
# [('property', 'http://www.wikidata.org/prop/direct/P495'), ('propertyName', 'country of origin')]
# [('property', 'http://www.wikidata.org/prop/direct/P4969'), ('propertyName', 'derivative work')]
# [('property', 'http://www.wikidata.org/prop/direct/P1889'), ('propertyName', 'different from')]
# [('property', 'http://www.wikidata.org/prop/direct/P57'), ('propertyName', 'director')]
# [('property', 'http://www.wikidata.org/prop/direct/P344'), ('propertyName', 'director of photography')]
# [('property', 'http://www.wikidata.org/prop/direct/P750'), ('propertyName', 'distributed by')]
# [('property', 'http://www.wikidata.org/prop/direct/P437'), ('propertyName', 'distribution format')]
# [('property', 'http://www.wikidata.org/prop/direct/P2047'), ('propertyName', 'duration')]
# [('property', 'http://www.wikidata.org/prop/direct/P3143'), ('propertyName', 'elFilm film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1431'), ('propertyName', 'executive producer')]
# [('property', 'http://www.wikidata.org/prop/direct/P1040'), ('propertyName', 'film editor')]
# [('property', 'http://www.wikidata.org/prop/direct/P915'), ('propertyName', 'filming location')]
# [('property', 'http://www.wikidata.org/prop/direct/P156'), ('propertyName', 'followed by')]
# [('property', 'http://www.wikidata.org/prop/direct/P136'), ('propertyName', 'genre')]
# [('property', 'http://www.wikidata.org/prop/direct/P6398'), ('propertyName', 'iTunes movie ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P31'), ('propertyName', 'instance of')]
# [('property', 'http://www.wikidata.org/prop/direct/P921'), ('propertyName', 'main subject')]
# [('property', 'http://www.wikidata.org/prop/direct/P135'), ('propertyName', 'movement')]
# [('property', 'http://www.wikidata.org/prop/direct/P840'), ('propertyName', 'narrative location')]
# [('property', 'http://www.wikidata.org/prop/direct/P856'), ('propertyName', 'official website')]
# [('property', 'http://www.wikidata.org/prop/direct/P364'), ('propertyName', 'original language of film or TV show')]
# [('property', 'http://www.wikidata.org/prop/direct/P179'), ('propertyName', 'part of the series')]
# [('property', 'http://www.wikidata.org/prop/direct/P175'), ('propertyName', 'performer')]
# [('property', 'http://www.wikidata.org/prop/direct/P162'), ('propertyName', 'producer')]
# [('property', 'http://www.wikidata.org/prop/direct/P272'), ('propertyName', 'production company')]
# [('property', 'http://www.wikidata.org/prop/direct/P2554'), ('propertyName', 'production designer')]
# [('property', 'http://www.wikidata.org/prop/direct/P577'), ('propertyName', 'publication date')]
# [('property', 'http://www.wikidata.org/prop/direct/P58'), ('propertyName', 'screenwriter')]
# [('property', 'http://www.wikidata.org/prop/direct/P9215'), ('propertyName', 'set during recurring event')]
# [('property', 'http://www.wikidata.org/prop/direct/P8411'), ('propertyName', 'set in environment')]
# [('property', 'http://www.wikidata.org/prop/direct/P2408'), ('propertyName', 'set in period')]
# [('property', 'http://www.wikidata.org/prop/direct/P1434'), ('propertyName', 'takes place in fictional universe')]
# [('property', 'http://www.wikidata.org/prop/direct/P1476'), ('propertyName', 'title')]
# [('property', 'http://www.wikidata.org/prop/direct/P2529'), ('propertyName', 'ČSFD film ID')]
# 100

# %%
# Return all properties ingoin from Halloween film
queryString = """
SELECT DISTINCT ?property ?propertyName
WHERE { 

    # ?object ?property wd:Q221103.
    # ?property <http://schema.org/name> ?propertyName.
} 
ORDER BY ?propertyName
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('property', 'http://www.wikidata.org/prop/direct/P144'), ('propertyName', 'based on')]
# [('property', 'http://www.wikidata.org/prop/direct/P4584'), ('propertyName', 'first appearance')]
# [('property', 'http://www.wikidata.org/prop/direct/P155'), ('propertyName', 'follows')]
# [('property', 'http://www.wikidata.org/prop/direct/P527'), ('propertyName', 'has part')]
# [('property', 'http://www.wikidata.org/prop/direct/P840'), ('propertyName', 'narrative location')]
# [('property', 'http://www.wikidata.org/prop/direct/P800'), ('propertyName', 'notable work')]
# [('property', 'http://www.wikidata.org/prop/direct/P1441'), ('propertyName', 'present in work')]
# [('property', 'http://www.wikidata.org/prop/direct/P1056'), ('propertyName', 'product or material produced')]
# [('property', 'http://www.wikidata.org/prop/direct/P6166'), ('propertyName', 'quotes work')]
# 9

# %%
# Return all workers related to the Halloween film by the following relation
# "performer"
queryString = """
SELECT DISTINCT ?performer ?performerName
WHERE { 

    wd:Q1243029 ?property ?performer.
    # ?performer <http://schema.org/name> ?performerName.
    
    FILTER(?property = wdt:P175)
} 
ORDER BY ?performer
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('performer', 'http://www.wikidata.org/entity/Q664025'), ('performerName', 'Harry Manfredini')]
# 1

# %%
# Return all workers related to the Friday the 13th film by the following relation
# "performer"
queryString = """
SELECT DISTINCT ?performer ?performerName
WHERE { 

    wd:Q1243029 ?property ?performer.
    # ?performer <http://schema.org/name> ?performerName.
    
    FILTER(?property = wdt:P175)
} 
ORDER BY ?performer
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('performer', 'http://www.wikidata.org/entity/Q664025'), ('performerName', 'Harry Manfredini')]
# 1

# %%
# Return all outgoing properties from Halloween and Friday the 13th films
queryString = """
SELECT DISTINCT ?property ?propertyName
WHERE { 

    {
        wd:Q221103 ?property ?object.
        # ?property <http://schema.org/name> ?propertyName.
    }
    UNION
    {
        wd:Q1243029 ?property ?object.
        # ?property <http://schema.org/name> ?propertyName.
    }
} 
ORDER BY ?propertyName
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('property', 'http://www.wikidata.org/prop/direct/P3593'), ('propertyName', 'AFI Catalog of Feature Films ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1562'), ('propertyName', 'AllMovie title ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2465'), ('propertyName', 'Allcinema film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1265'), ('propertyName', 'AlloCiné film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P9586'), ('propertyName', 'Apple TV movie ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4632'), ('propertyName', 'Bechdel Test Movie List ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1237'), ('propertyName', 'Box Office Mojo film ID (former scheme)')]
# [('property', 'http://www.wikidata.org/prop/direct/P2758'), ('propertyName', 'CNC film rating (France)')]
# [('property', 'http://www.wikidata.org/prop/direct/P4665'), ('propertyName', 'CineMagia title ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3933'), ('propertyName', 'Cinema.de ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3077'), ('propertyName', 'Cineplex Germany film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3203'), ('propertyName', 'Ciné-Ressources film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4276'), ('propertyName', 'Cinémathèque québécoise work identifier')]
# [('property', 'http://www.wikidata.org/prop/direct/P5905'), ('propertyName', 'Comic Vine ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1804'), ('propertyName', 'DNF film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4277'), ('propertyName', 'Daum movie ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3844'), ('propertyName', 'Deutsche Synchronkartei film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4529'), ('propertyName', 'Douban film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3141'), ('propertyName', 'EDb film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2704'), ('propertyName', 'EIDR content ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2346'), ('propertyName', 'Elonet movie ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1417'), ('propertyName', 'Encyclopædia Britannica Online ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5693'), ('propertyName', 'Fandango film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7970'), ('propertyName', 'FandangoNow ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6262'), ('propertyName', 'Fandom article ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P480'), ('propertyName', 'FilmAffinity ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7975'), ('propertyName', 'Filmfront film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2747'), ('propertyName', 'Filmiroda rating')]
# [('property', 'http://www.wikidata.org/prop/direct/P5032'), ('propertyName', 'Filmweb.pl film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P646'), ('propertyName', 'Freebase ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P227'), ('propertyName', 'GND ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6562'), ('propertyName', 'Google Play Movies & TV ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6466'), ('propertyName', 'Hulu movie ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P345'), ('propertyName', 'IMDb ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3212'), ('propertyName', 'ISAN')]
# [('property', 'http://www.wikidata.org/prop/direct/P5099'), ('propertyName', 'Il mondo dei doppiatori ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2508'), ('propertyName', 'KINENOTE film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2603'), ('propertyName', 'Kinopoisk film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4282'), ('propertyName', 'LUMIERE film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6058'), ('propertyName', 'Larousse ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3107'), ('propertyName', 'LdiF ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6127'), ('propertyName', 'Letterboxd film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P244'), ('propertyName', 'Library of Congress authority ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4780'), ('propertyName', 'MYmovies movie ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5970'), ('propertyName', 'Medierådet rating')]
# [('property', 'http://www.wikidata.org/prop/direct/P1712'), ('propertyName', 'Metacritic ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P8033'), ('propertyName', 'Movie Review Query Engine ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2509'), ('propertyName', 'Movie Walker film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1970'), ('propertyName', 'MovieMeter film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5786'), ('propertyName', 'Moviepilot.de film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1874'), ('propertyName', 'Netflix ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3138'), ('propertyName', 'OFDb film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3302'), ('propertyName', 'Open Media Database film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P905'), ('propertyName', 'PORT film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1258'), ('propertyName', 'Rotten Tomatoes ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2518'), ('propertyName', 'Scope.dk film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2334'), ('propertyName', 'Swedish Film Database film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2631'), ('propertyName', 'TCM Movie Database film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4947'), ('propertyName', 'TMDb movie ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3804'), ('propertyName', 'TV Guide show ID (former scheme)')]
# [('property', 'http://www.wikidata.org/prop/direct/P2638'), ('propertyName', 'TV.com ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3808'), ('propertyName', 'The Numbers movie ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P214'), ('propertyName', 'VIAF ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7334'), ('propertyName', 'Vudu video ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2061'), ('propertyName', 'aspect ratio')]
# [('property', 'http://www.wikidata.org/prop/direct/P5021'), ('propertyName', 'assessment')]
# [('property', 'http://www.wikidata.org/prop/direct/P166'), ('propertyName', 'award received')]
# [('property', 'http://www.wikidata.org/prop/direct/P161'), ('propertyName', 'cast member')]
# [('property', 'http://www.wikidata.org/prop/direct/P674'), ('propertyName', 'characters')]
# [('property', 'http://www.wikidata.org/prop/direct/P3129'), ('propertyName', 'cine.gr film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P462'), ('propertyName', 'color')]
# [('property', 'http://www.wikidata.org/prop/direct/P86'), ('propertyName', 'composer')]
# [('property', 'http://www.wikidata.org/prop/direct/P2130'), ('propertyName', 'cost')]
# [('property', 'http://www.wikidata.org/prop/direct/P495'), ('propertyName', 'country of origin')]
# [('property', 'http://www.wikidata.org/prop/direct/P4969'), ('propertyName', 'derivative work')]
# [('property', 'http://www.wikidata.org/prop/direct/P1889'), ('propertyName', 'different from')]
# [('property', 'http://www.wikidata.org/prop/direct/P57'), ('propertyName', 'director')]
# [('property', 'http://www.wikidata.org/prop/direct/P344'), ('propertyName', 'director of photography')]
# [('property', 'http://www.wikidata.org/prop/direct/P750'), ('propertyName', 'distributed by')]
# [('property', 'http://www.wikidata.org/prop/direct/P437'), ('propertyName', 'distribution format')]
# [('property', 'http://www.wikidata.org/prop/direct/P2047'), ('propertyName', 'duration')]
# [('property', 'http://www.wikidata.org/prop/direct/P3143'), ('propertyName', 'elFilm film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1431'), ('propertyName', 'executive producer')]
# [('property', 'http://www.wikidata.org/prop/direct/P2755'), ('propertyName', 'exploitation visa number')]
# [('property', 'http://www.wikidata.org/prop/direct/P1040'), ('propertyName', 'film editor')]
# [('property', 'http://www.wikidata.org/prop/direct/P915'), ('propertyName', 'filming location')]
# [('property', 'http://www.wikidata.org/prop/direct/P156'), ('propertyName', 'followed by')]
# [('property', 'http://www.wikidata.org/prop/direct/P136'), ('propertyName', 'genre')]
# [('property', 'http://www.wikidata.org/prop/direct/P6398'), ('propertyName', 'iTunes movie ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P18'), ('propertyName', 'image')]
# [('property', 'http://www.wikidata.org/prop/direct/P31'), ('propertyName', 'instance of')]
# [('property', 'http://www.wikidata.org/prop/direct/P921'), ('propertyName', 'main subject')]
# [('property', 'http://www.wikidata.org/prop/direct/P135'), ('propertyName', 'movement')]
# [('property', 'http://www.wikidata.org/prop/direct/P840'), ('propertyName', 'narrative location')]
# [('property', 'http://www.wikidata.org/prop/direct/P1411'), ('propertyName', 'nominated for')]
# [('property', 'http://www.wikidata.org/prop/direct/P856'), ('propertyName', 'official website')]
# [('property', 'http://www.wikidata.org/prop/direct/P364'), ('propertyName', 'original language of film or TV show')]
# [('property', 'http://www.wikidata.org/prop/direct/P179'), ('propertyName', 'part of the series')]
# [('property', 'http://www.wikidata.org/prop/direct/P175'), ('propertyName', 'performer')]
# [('property', 'http://www.wikidata.org/prop/direct/P162'), ('propertyName', 'producer')]
# [('property', 'http://www.wikidata.org/prop/direct/P272'), ('propertyName', 'production company')]
# [('property', 'http://www.wikidata.org/prop/direct/P2554'), ('propertyName', 'production designer')]
# [('property', 'http://www.wikidata.org/prop/direct/P577'), ('propertyName', 'publication date')]
# [('property', 'http://www.wikidata.org/prop/direct/P58'), ('propertyName', 'screenwriter')]
# [('property', 'http://www.wikidata.org/prop/direct/P9215'), ('propertyName', 'set during recurring event')]
# [('property', 'http://www.wikidata.org/prop/direct/P8411'), ('propertyName', 'set in environment')]
# [('property', 'http://www.wikidata.org/prop/direct/P2408'), ('propertyName', 'set in period')]
# [('property', 'http://www.wikidata.org/prop/direct/P1434'), ('propertyName', 'takes place in fictional universe')]
# [('property', 'http://www.wikidata.org/prop/direct/P1476'), ('propertyName', 'title')]
# [('property', 'http://www.wikidata.org/prop/direct/P2529'), ('propertyName', 'ČSFD film ID')]
# 110

# %%
# Return all ingoing properties from Halloween and Friday the 13th films
queryString = """
SELECT DISTINCT ?property ?propertyName
WHERE { 

    {
        # ?object ?property wd:Q221103.
        # ?property <http://schema.org/name> ?propertyName.
    }
    UNION
    {
        # ?object ?property wd:Q1243029.
        # ?property <http://schema.org/name> ?propertyName.
    }
} 
ORDER BY ?propertyName
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('property', 'http://www.wikidata.org/prop/direct/P144'), ('propertyName', 'based on')]
# [('property', 'http://www.wikidata.org/prop/direct/P161'), ('propertyName', 'cast member')]
# [('property', 'http://www.wikidata.org/prop/direct/P4584'), ('propertyName', 'first appearance')]
# [('property', 'http://www.wikidata.org/prop/direct/P155'), ('propertyName', 'follows')]
# [('property', 'http://www.wikidata.org/prop/direct/P527'), ('propertyName', 'has part')]
# [('property', 'http://www.wikidata.org/prop/direct/P840'), ('propertyName', 'narrative location')]
# [('property', 'http://www.wikidata.org/prop/direct/P800'), ('propertyName', 'notable work')]
# [('property', 'http://www.wikidata.org/prop/direct/P1441'), ('propertyName', 'present in work')]
# [('property', 'http://www.wikidata.org/prop/direct/P1056'), ('propertyName', 'product or material produced')]
# [('property', 'http://www.wikidata.org/prop/direct/P6166'), ('propertyName', 'quotes work')]
# 10

# %%
# Return people that worked for Halloween with the following relations
# "cast member", "director", "director of photography", "performer", "producer", "production designer",
# "screenwriter", "composer", "executive prodicer"
queryString = """
SELECT DISTINCT ?workerName (GROUP_CONCAT(?propertyName; separator=" ,") AS ?role) 
WHERE { 

    wd:Q221103 ?property ?worker.
    
    # ?worker <http://schema.org/name> ?workerName.
    
    # ?property <http://schema.org/name> ?propertyName.
    FILTER(?property = wdt:P161 || ?property = wdt:P57 || ?property = wdt:P344 || ?property = wdt:P175 
    || ?property = wdt:P162 || ?property = wdt:2554 || ?property = wdt:P58 || ?property = wdt:P86 || ?property = wdt:P1431)

} 
GROUP BY ?workerName
ORDER BY ?workerName
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('workerName', 'Arthur Malet'), ('role', 'cast member')]
# [('workerName', 'Charles Cyphers'), ('role', 'cast member')]
# [('workerName', 'Dean Cundey'), ('role', 'director of photography')]
# [('workerName', 'Debra Hill'), ('role', 'producer ,screenwriter')]
# [('workerName', 'Donald Pleasence'), ('role', 'cast member')]
# [('workerName', 'Gabriel Cattand'), ('role', 'cast member')]
# [('workerName', 'Irwin Yablans'), ('role', 'producer')]
# [('workerName', 'Jamie Lee Curtis'), ('role', 'cast member')]
# [('workerName', 'John Carpenter'), ('role', 'cast member ,performer ,director ,screenwriter ,composer')]
# [('workerName', 'John Michael Graham'), ('role', 'cast member')]
# [('workerName', 'Kyle Richards'), ('role', 'cast member')]
# [('workerName', 'Moustapha Akkad'), ('role', 'producer ,executive producer')]
# [('workerName', 'Nancy Kyes'), ('role', 'cast member')]
# [('workerName', 'Nancy Stephens'), ('role', 'cast member')]
# [('workerName', 'Nick Castle'), ('role', 'cast member')]
# [('workerName', 'P. J. Soles'), ('role', 'cast member')]
# [('workerName', 'Tony Moran'), ('role', 'cast member')]
# 17

# %%
# Return people that worked for Friday the 13th with the following relations
# "cast member", "director", "director of photography", "performer", "producer", "production designer",
# "screenwriter", "composer", "executive prodicer"
queryString = """
SELECT DISTINCT ?workerName (GROUP_CONCAT(?propertyName; separator=" ,") AS ?role) 
WHERE { 

    wd:Q1243029 ?property ?worker.
    
    # ?worker <http://schema.org/name> ?workerName.
    
    # ?property <http://schema.org/name> ?propertyName.
    FILTER(?property = wdt:P161 || ?property = wdt:P57 || ?property = wdt:P344 || ?property = wdt:P175 
    || ?property = wdt:P162 || ?property = wdt:2554 || ?property = wdt:P58 || ?property = wdt:P86 || ?property = wdt:P1431)

} 
GROUP BY ?workerName
ORDER BY ?workerName
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('workerName', 'Adrienne King'), ('role', 'cast member')]
# [('workerName', 'Ari Lehman'), ('role', 'cast member')]
# [('workerName', 'Barry Abrams'), ('role', 'director of photography')]
# [('workerName', 'Betsy Palmer'), ('role', 'cast member')]
# [('workerName', 'Harry Crosby'), ('role', 'cast member')]
# [('workerName', 'Harry Manfredini'), ('role', 'performer ,composer')]
# [('workerName', 'Jeannine Taylor'), ('role', 'cast member')]
# [('workerName', 'Kevin Bacon'), ('role', 'cast member')]
# [('workerName', 'Laurie Bartram'), ('role', 'cast member')]
# [('workerName', 'Rex Everhart'), ('role', 'cast member')]
# [('workerName', 'Robbi Morgan'), ('role', 'cast member')]
# [('workerName', 'Sean S. Cunningham'), ('role', 'producer ,director')]
# [('workerName', 'Victor Miller'), ('role', 'screenwriter')]
# 13

# %%
# Investigate the workers of the two original movies and check any commonality
queryString = """
SELECT ?workerName (GROUP_CONCAT(DISTINCT ?filmTitle; separator=" ,") AS ?workedIn) (GROUP_CONCAT(?propertyName; separator=" ,") AS ?role)
WHERE { 

    {
        wd:Q221103 ?property ?worker.
        wd:Q221103 wdt:P1476 ?filmTitle.
    }
    UNION
    {
        wd:Q1243029 ?property ?worker.
        wd:Q1243029 wdt:P1476 ?filmTitle.
    }
    
    # ?worker <http://schema.org/name> ?workerName.
    
    # ?property <http://schema.org/name> ?propertyName.
    FILTER(?property = wdt:P161 || ?property = wdt:P57 || ?property = wdt:P344 || ?property = wdt:P175 
    || ?property = wdt:P162 || ?property = wdt:2554 || ?property = wdt:P58 || ?property = wdt:P86 || ?property = wdt:P1431)

} 
GROUP BY ?workerName
ORDER BY ?workerName
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('workerName', 'Adrienne King'), ('workedIn', 'Friday the 13th'), ('role', 'cast member')]
# [('workerName', 'Ari Lehman'), ('workedIn', 'Friday the 13th'), ('role', 'cast member')]
# [('workerName', 'Arthur Malet'), ('workedIn', 'Halloween'), ('role', 'cast member')]
# [('workerName', 'Barry Abrams'), ('workedIn', 'Friday the 13th'), ('role', 'director of photography')]
# [('workerName', 'Betsy Palmer'), ('workedIn', 'Friday the 13th'), ('role', 'cast member')]
# [('workerName', 'Charles Cyphers'), ('workedIn', 'Halloween'), ('role', 'cast member')]
# [('workerName', 'Dean Cundey'), ('workedIn', 'Halloween'), ('role', 'director of photography')]
# [('workerName', 'Debra Hill'), ('workedIn', 'Halloween'), ('role', 'producer ,screenwriter')]
# [('workerName', 'Donald Pleasence'), ('workedIn', 'Halloween'), ('role', 'cast member')]
# [('workerName', 'Gabriel Cattand'), ('workedIn', 'Halloween'), ('role', 'cast member')]
# [('workerName', 'Harry Crosby'), ('workedIn', 'Friday the 13th'), ('role', 'cast member')]
# [('workerName', 'Harry Manfredini'), ('workedIn', 'Friday the 13th'), ('role', 'performer ,composer')]
# [('workerName', 'Irwin Yablans'), ('workedIn', 'Halloween'), ('role', 'producer')]
# [('workerName', 'Jamie Lee Curtis'), ('workedIn', 'Halloween'), ('role', 'cast member')]
# [('workerName', 'Jeannine Taylor'), ('workedIn', 'Friday the 13th'), ('role', 'cast member')]
# [('workerName', 'John Carpenter'), ('workedIn', 'Halloween'), ('role', 'director ,composer ,cast member ,screenwriter ,performer')]
# [('workerName', 'John Michael Graham'), ('workedIn', 'Halloween'), ('role', 'cast member')]
# [('workerName', 'Kevin Bacon'), ('workedIn', 'Friday the 13th'), ('role', 'cast member')]
# [('workerName', 'Kyle Richards'), ('workedIn', 'Halloween'), ('role', 'cast member')]
# [('workerName', 'Laurie Bartram'), ('workedIn', 'Friday the 13th'), ('role', 'cast member')]
# [('workerName', 'Moustapha Akkad'), ('workedIn', 'Halloween'), ('role', 'executive producer ,producer')]
# [('workerName', 'Nancy Kyes'), ('workedIn', 'Halloween'), ('role', 'cast member')]
# [('workerName', 'Nancy Stephens'), ('workedIn', 'Halloween'), ('role', 'cast member')]
# [('workerName', 'Nick Castle'), ('workedIn', 'Halloween'), ('role', 'cast member')]
# [('workerName', 'P. J. Soles'), ('workedIn', 'Halloween'), ('role', 'cast member')]
# [('workerName', 'Rex Everhart'), ('workedIn', 'Friday the 13th'), ('role', 'cast member')]
# [('workerName', 'Robbi Morgan'), ('workedIn', 'Friday the 13th'), ('role', 'cast member')]
# [('workerName', 'Sean S. Cunningham'), ('workedIn', 'Friday the 13th'), ('role', 'director ,producer')]
# [('workerName', 'Tony Moran'), ('workedIn', 'Halloween'), ('role', 'cast member')]
# [('workerName', 'Victor Miller'), ('workedIn', 'Friday the 13th'), ('role', 'screenwriter')]
# 30

# %% [markdown]
# ### Point 1 Finish
#
# DESCRIPTION: I started by checking all ingoing and outgoing properties from both the given films.
# From that I decided to keep all the following relations: "cast member" wdt:P161, "director" wdt:P57, "director of photography"wdt:P344, "performer" wdt:P175, "producer" wdt:P162, "production designer" wdt:2554, "screenwriter" wdt:P58, "composer" wdt:P86, "executive producer" wdt:P1431. All these relations connect the film to the worker.
#
#
# RESULT: The result shows the name of all the people that have worked for both films along with their role. We can observe that “John Carpenter” is the one with the most roles.

# %% [markdown]
# ### Task 2

# %%
# Return all distinct professions of cast member in both films
queryString = """
SELECT DISTINCT ?profession ?professionName
WHERE { 

    {
        wd:Q221103 wdt:P161 ?worker.
    }
    UNION
    {
        wd:Q1243029 wdt:P161 ?worker.
    }
    
    
    # ?worker <http://schema.org/name> ?workerName.
    # ?worker wdt:P106 ?profession.
    # ?profession <http://schema.org/name> ?professionName.

} 
ORDER BY ?professionName
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('profession', 'http://www.wikidata.org/entity/Q33999'), ('professionName', 'actor')]
# [('profession', 'http://www.wikidata.org/entity/Q805221'), ('professionName', 'ballet dancer')]
# [('profession', 'http://www.wikidata.org/entity/Q806798'), ('professionName', 'banker')]
# [('profession', 'http://www.wikidata.org/entity/Q948329'), ('professionName', 'character actor')]
# [('profession', 'http://www.wikidata.org/entity/Q4853732'), ('professionName', "children's writer")]
# [('profession', 'http://www.wikidata.org/entity/Q36834'), ('professionName', 'composer')]
# [('profession', 'http://www.wikidata.org/entity/Q5716684'), ('professionName', 'dancer')]
# [('profession', 'http://www.wikidata.org/entity/Q3455803'), ('professionName', 'director')]
# [('profession', 'http://www.wikidata.org/entity/Q11481802'), ('professionName', 'dub actor')]
# [('profession', 'http://www.wikidata.org/entity/Q10800557'), ('professionName', 'film actor')]
# [('profession', 'http://www.wikidata.org/entity/Q2526255'), ('professionName', 'film director')]
# [('profession', 'http://www.wikidata.org/entity/Q7042855'), ('professionName', 'film editor')]
# [('profession', 'http://www.wikidata.org/entity/Q3282637'), ('professionName', 'film producer')]
# [('profession', 'http://www.wikidata.org/entity/Q1415090'), ('professionName', 'film score composer')]
# [('profession', 'http://www.wikidata.org/entity/Q2883465'), ('professionName', 'investment banker')]
# [('profession', 'http://www.wikidata.org/entity/Q13235160'), ('professionName', 'manufacturer')]
# [('profession', 'http://www.wikidata.org/entity/Q639669'), ('professionName', 'musician')]
# [('profession', 'http://www.wikidata.org/entity/Q1028181'), ('professionName', 'painter')]
# [('profession', 'http://www.wikidata.org/entity/Q28389'), ('professionName', 'screenwriter')]
# [('profession', 'http://www.wikidata.org/entity/Q1281618'), ('professionName', 'sculptor')]
# [('profession', 'http://www.wikidata.org/entity/Q177220'), ('professionName', 'singer')]
# [('profession', 'http://www.wikidata.org/entity/Q2259451'), ('professionName', 'stage actor')]
# [('profession', 'http://www.wikidata.org/entity/Q10798782'), ('professionName', 'television actor')]
# [('profession', 'http://www.wikidata.org/entity/Q2405480'), ('professionName', 'voice actor')]
# [('profession', 'http://www.wikidata.org/entity/Q897317'), ('professionName', 'winegrower')]
# [('profession', 'http://www.wikidata.org/entity/Q36180'), ('professionName', 'writer')]
# 26

# %%
# Return all distinct properties of cast member in both films
queryString = """
SELECT DISTINCT ?property ?propertyName
WHERE { 

    {
        wd:Q221103 wdt:P161 ?castMember.
    }
    UNION
    {
        wd:Q1243029 wdt:P161 ?castMember.
    }
    
    
    # ?castMember ?property ?object.
    # ?property <http://schema.org/name> ?propertyName.

} 
ORDER BY ?propertyName
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('property', 'http://www.wikidata.org/prop/direct/P7119'), ('propertyName', 'AMPAS collections person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7109'), ('propertyName', 'Acharts.co artist ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P8895'), ('propertyName', 'All the Tropes identifier')]
# [('property', 'http://www.wikidata.org/prop/direct/P2019'), ('propertyName', 'AllMovie person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1728'), ('propertyName', 'AllMusic artist ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7214'), ('propertyName', 'Allcinema person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1266'), ('propertyName', 'AlloCiné person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5340'), ('propertyName', 'American Film Institute person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2850'), ('propertyName', 'Apple Music artist ID (American version)')]
# [('property', 'http://www.wikidata.org/prop/direct/P7184'), ('propertyName', 'Awards & Winners artist ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4326'), ('propertyName', 'BFI Filmography person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4438'), ('propertyName', 'BFI Films, TV and people ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5361'), ('propertyName', 'BNB person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3630'), ('propertyName', 'Babelio author ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3283'), ('propertyName', 'Bandcamp ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5007'), ('propertyName', 'Behind The Voice Actors person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P950'), ('propertyName', 'Biblioteca Nacional de España ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P268'), ('propertyName', 'Bibliothèque nationale de France ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2688'), ('propertyName', 'Box Office Mojo person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5019'), ('propertyName', 'Brockhaus Enzyklopädie online ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2190'), ('propertyName', 'C-SPAN person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1273'), ('propertyName', 'CANTIC ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1890'), ('propertyName', 'CCAB ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1280'), ('propertyName', 'CONOR.SI ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P8179'), ('propertyName', 'Canadiana NCF ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4104'), ('propertyName', 'Carnegie Hall agent ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P271'), ('propertyName', 'CiNii author ID (books)')]
# [('property', 'http://www.wikidata.org/prop/direct/P3933'), ('propertyName', 'Cinema.de ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3204'), ('propertyName', 'Ciné-Ressources person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P8971'), ('propertyName', 'Cinémathèque québécoise person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5905'), ('propertyName', 'Comic Vine ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P373'), ('propertyName', 'Commons category')]
# [('property', 'http://www.wikidata.org/prop/direct/P935'), ('propertyName', 'Commons gallery')]
# [('property', 'http://www.wikidata.org/prop/direct/P6521'), ('propertyName', 'Crew United person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3846'), ('propertyName', 'DBC author ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2626'), ('propertyName', 'Danish National Filmography person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7803'), ('propertyName', 'Decine21 person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2722'), ('propertyName', 'Deezer artist ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7902'), ('propertyName', 'Deutsche Biographie (GND) ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4332'), ('propertyName', 'Deutsche Synchronkartei actor ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1953'), ('propertyName', 'Discogs artist ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6181'), ('propertyName', 'Disney A to Z ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5284'), ('propertyName', 'Douban movie celebrity ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3142'), ('propertyName', 'EDb person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2387'), ('propertyName', 'Elonet person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P9430'), ('propertyName', 'Encyclopedia of Jewish Women ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1417'), ('propertyName', 'Encyclopædia Britannica Online ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3219'), ('propertyName', 'Encyclopædia Universalis ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7704'), ('propertyName', 'Europeana entity')]
# [('property', 'http://www.wikidata.org/prop/direct/P5617'), ('propertyName', 'Evene ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2163'), ('propertyName', 'FAST ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2013'), ('propertyName', 'Facebook ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6262'), ('propertyName', 'Fandom article ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6722'), ('propertyName', 'FemBio ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P8796'), ('propertyName', 'FilmPolski press collection ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5254'), ('propertyName', 'FilmTv.it person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2639'), ('propertyName', 'Filmportal ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5033'), ('propertyName', 'Filmweb.pl person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P535'), ('propertyName', 'Find A Grave memorial ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P646'), ('propertyName', 'Freebase ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7818'), ('propertyName', 'French Vikidia ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P227'), ('propertyName', 'GND ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1741'), ('propertyName', 'GTAA ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P8094'), ('propertyName', 'GeneaStar person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2600'), ('propertyName', 'Geni.com profile ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2963'), ('propertyName', 'Goodreads author ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1296'), ('propertyName', 'Gran Enciclopèdia Catalana ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6868'), ('propertyName', 'Hoopla artist ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7982'), ('propertyName', 'Hrvatska enciklopedija ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P345'), ('propertyName', 'IMDb ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P213'), ('propertyName', 'ISNI')]
# [('property', 'http://www.wikidata.org/prop/direct/P269'), ('propertyName', 'IdRef ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2003'), ('propertyName', 'Instagram username')]
# [('property', 'http://www.wikidata.org/prop/direct/P1220'), ('propertyName', 'Internet Broadway Database person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4456'), ('propertyName', 'Internet Off-Broadway Database creditable entity ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1233'), ('propertyName', 'Internet Speculative Fiction Database author ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3305'), ('propertyName', 'KINENOTE person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1649'), ('propertyName', 'KMDb person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3051'), ('propertyName', 'Kindred Britain ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2604'), ('propertyName', 'Kinopoisk person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P8637'), ('propertyName', "L'Officiel des spectacles ID")]
# [('property', 'http://www.wikidata.org/prop/direct/P1368'), ('propertyName', 'LNB ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4283'), ('propertyName', 'LUMIERE director ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3192'), ('propertyName', 'Last.fm ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1977'), ('propertyName', 'Les Archives du Spectacle Person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P409'), ('propertyName', 'Libraries Australia ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P244'), ('propertyName', 'Library of Congress authority ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7400'), ('propertyName', 'LibraryThing author ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7836'), ('propertyName', 'Livelib.ru person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4779'), ('propertyName', 'MYmovies actor ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1712'), ('propertyName', 'Metacritic ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1969'), ('propertyName', 'MovieMeter director ID (former scheme)')]
# [('property', 'http://www.wikidata.org/prop/direct/P4782'), ('propertyName', 'Movieplayer person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1284'), ('propertyName', 'Munzinger person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P434'), ('propertyName', 'MusicBrainz artist ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5882'), ('propertyName', 'Muziekweb performer ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4084'), ('propertyName', 'MyAnimeList people ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3265'), ('propertyName', 'Myspace ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3222'), ('propertyName', 'NE.se ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P691'), ('propertyName', 'NKCR AUT ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1315'), ('propertyName', 'NLA Trove ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1695'), ('propertyName', 'NLP ID (unique)')]
# [('property', 'http://www.wikidata.org/prop/direct/P1263'), ('propertyName', 'NNDB people ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1015'), ('propertyName', 'NORAF ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1375'), ('propertyName', 'NSK ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1207'), ('propertyName', 'NUKAT ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P349'), ('propertyName', 'National Diet Library ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4619'), ('propertyName', 'National Library of Brazil ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P949'), ('propertyName', 'National Library of Israel ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P8189'), ('propertyName', 'National Library of Israel J9U ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7369'), ('propertyName', 'National Library of Chile ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7699'), ('propertyName', 'National Library of Lithuania ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5034'), ('propertyName', 'National Library of Korea ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1816'), ('propertyName', 'National Portrait Gallery (London) person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1006'), ('propertyName', 'Nationale Thesaurus voor Auteurs ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P9404'), ('propertyName', 'OFDb person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P648'), ('propertyName', 'Open Library ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5534'), ('propertyName', 'Open Media Database person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1415'), ('propertyName', 'Oxford Dictionary of National Biography ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7293'), ('propertyName', 'PLWABN ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2435'), ('propertyName', 'PORT person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P9743'), ('propertyName', 'Podchaser creator ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1005'), ('propertyName', 'Portuguese National Library ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4515'), ('propertyName', 'Prisma ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P8349'), ('propertyName', 'Proleksis enciklopedija ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3417'), ('propertyName', 'Quora topic ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3065'), ('propertyName', 'RERO ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5404'), ('propertyName', 'Rate Your Music artist ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1185'), ('propertyName', 'Rodovid ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7929'), ('propertyName', 'Roglo person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3017'), ('propertyName', 'Rolling Stone artist ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1258'), ('propertyName', 'Rotten Tomatoes ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3987'), ('propertyName', 'SHARE Catalogue author ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3430'), ('propertyName', 'SNAC ARK ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P9807'), ('propertyName', 'SNK ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2519'), ('propertyName', 'Scope.dk person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2909'), ('propertyName', 'SecondHandSongs artist ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7700'), ('propertyName', 'Slovak National Library ID (VIAF)')]
# [('property', 'http://www.wikidata.org/prop/direct/P3478'), ('propertyName', 'Songkick artist ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3040'), ('propertyName', 'SoundCloud ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1902'), ('propertyName', 'Spotify artist ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4342'), ('propertyName', 'Store norske leksikon ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2168'), ('propertyName', 'Swedish Film Database person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3056'), ('propertyName', 'TCM Movie Database person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4985'), ('propertyName', 'TMDb person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6839'), ('propertyName', 'TV Tropes identifier')]
# [('property', 'http://www.wikidata.org/prop/direct/P2638'), ('propertyName', 'TV.com ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5357'), ('propertyName', 'The Encyclopedia of Science Fiction ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4657'), ('propertyName', 'The Numbers person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4638'), ('propertyName', 'The Peerage person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2469'), ('propertyName', 'Theatricalia person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7085'), ('propertyName', 'TikTok username')]
# [('property', 'http://www.wikidata.org/prop/direct/P5421'), ('propertyName', 'Trading Card Database person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3365'), ('propertyName', 'Treccani ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2002'), ('propertyName', 'Twitter username')]
# [('property', 'http://www.wikidata.org/prop/direct/P3980'), ('propertyName', 'Unifrance person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P9328'), ('propertyName', 'Universal Music France artist ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1580'), ('propertyName', 'University of Barcelona authority ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P214'), ('propertyName', 'VIAF ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6517'), ('propertyName', 'WhoSampled artist ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2949'), ('propertyName', 'WikiTree person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7859'), ('propertyName', 'WorldCat Identities ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1553'), ('propertyName', 'Yandex Music artist ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2397'), ('propertyName', 'YouTube channel ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6844'), ('propertyName', 'abART person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P66'), ('propertyName', 'ancestral home')]
# [('property', 'http://www.wikidata.org/prop/direct/P485'), ('propertyName', 'archives at')]
# [('property', 'http://www.wikidata.org/prop/direct/P166'), ('propertyName', 'award received')]
# [('property', 'http://www.wikidata.org/prop/direct/P1477'), ('propertyName', 'birth name')]
# [('property', 'http://www.wikidata.org/prop/direct/P509'), ('propertyName', 'cause of death')]
# [('property', 'http://www.wikidata.org/prop/direct/P40'), ('propertyName', 'child')]
# [('property', 'http://www.wikidata.org/prop/direct/P4768'), ('propertyName', 'cinematografo.it name or company ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7763'), ('propertyName', 'copyright status as a creator')]
# [('property', 'http://www.wikidata.org/prop/direct/P27'), ('propertyName', 'country of citizenship')]
# [('property', 'http://www.wikidata.org/prop/direct/P569'), ('propertyName', 'date of birth')]
# [('property', 'http://www.wikidata.org/prop/direct/P570'), ('propertyName', 'date of death')]
# [('property', 'http://www.wikidata.org/prop/direct/P1343'), ('propertyName', 'described by source')]
# [('property', 'http://www.wikidata.org/prop/direct/P1889'), ('propertyName', 'different from')]
# [('property', 'http://www.wikidata.org/prop/direct/P358'), ('propertyName', 'discography')]
# [('property', 'http://www.wikidata.org/prop/direct/P69'), ('propertyName', 'educated at')]
# [('property', 'http://www.wikidata.org/prop/direct/P3136'), ('propertyName', 'elCinema person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3144'), ('propertyName', 'elFilm person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P734'), ('propertyName', 'family name')]
# [('property', 'http://www.wikidata.org/prop/direct/P22'), ('propertyName', 'father')]
# [('property', 'http://www.wikidata.org/prop/direct/P5327'), ('propertyName', 'fernsehserien.de ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1283'), ('propertyName', 'filmography')]
# [('property', 'http://www.wikidata.org/prop/direct/P1819'), ('propertyName', 'genealogics.org person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P136'), ('propertyName', 'genre')]
# [('property', 'http://www.wikidata.org/prop/direct/P735'), ('propertyName', 'given name')]
# [('property', 'http://www.wikidata.org/prop/direct/P4359'), ('propertyName', 'gravsted.dk ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6379'), ('propertyName', 'has works in the collection')]
# [('property', 'http://www.wikidata.org/prop/direct/P18'), ('propertyName', 'image')]
# [('property', 'http://www.wikidata.org/prop/direct/P737'), ('propertyName', 'influenced by')]
# [('property', 'http://www.wikidata.org/prop/direct/P31'), ('propertyName', 'instance of')]
# [('property', 'http://www.wikidata.org/prop/direct/P1303'), ('propertyName', 'instrument')]
# [('property', 'http://www.wikidata.org/prop/direct/P7808'), ('propertyName', 'kino-teatr.ru person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1412'), ('propertyName', 'languages spoken, written or signed')]
# [('property', 'http://www.wikidata.org/prop/direct/P1196'), ('propertyName', 'manner of death')]
# [('property', 'http://www.wikidata.org/prop/direct/P463'), ('propertyName', 'member of')]
# [('property', 'http://www.wikidata.org/prop/direct/P102'), ('propertyName', 'member of political party')]
# [('property', 'http://www.wikidata.org/prop/direct/P241'), ('propertyName', 'military branch')]
# [('property', 'http://www.wikidata.org/prop/direct/P1347'), ('propertyName', 'military casualty classification')]
# [('property', 'http://www.wikidata.org/prop/direct/P25'), ('propertyName', 'mother')]
# [('property', 'http://www.wikidata.org/prop/direct/P1559'), ('propertyName', 'name in native language')]
# [('property', 'http://www.wikidata.org/prop/direct/P103'), ('propertyName', 'native language')]
# [('property', 'http://www.wikidata.org/prop/direct/P97'), ('propertyName', 'noble title')]
# [('property', 'http://www.wikidata.org/prop/direct/P1411'), ('propertyName', 'nominated for')]
# [('property', 'http://www.wikidata.org/prop/direct/P800'), ('propertyName', 'notable work')]
# [('property', 'http://www.wikidata.org/prop/direct/P1971'), ('propertyName', 'number of children')]
# [('property', 'http://www.wikidata.org/prop/direct/P106'), ('propertyName', 'occupation')]
# [('property', 'http://www.wikidata.org/prop/direct/P856'), ('propertyName', 'official website')]
# [('property', 'http://www.wikidata.org/prop/direct/P5008'), ('propertyName', 'on focus list of Wikimedia project')]
# [('property', 'http://www.wikidata.org/prop/direct/P3762'), ('propertyName', 'openMLOL author ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P19'), ('propertyName', 'place of birth')]
# [('property', 'http://www.wikidata.org/prop/direct/P119'), ('propertyName', 'place of burial')]
# [('property', 'http://www.wikidata.org/prop/direct/P20'), ('propertyName', 'place of death')]
# [('property', 'http://www.wikidata.org/prop/direct/P264'), ('propertyName', 'record label')]
# [('property', 'http://www.wikidata.org/prop/direct/P7084'), ('propertyName', 'related category')]
# [('property', 'http://www.wikidata.org/prop/direct/P1038'), ('propertyName', 'relative')]
# [('property', 'http://www.wikidata.org/prop/direct/P140'), ('propertyName', 'religion')]
# [('property', 'http://www.wikidata.org/prop/direct/P551'), ('propertyName', 'residence')]
# [('property', 'http://www.wikidata.org/prop/direct/P21'), ('propertyName', 'sex or gender')]
# [('property', 'http://www.wikidata.org/prop/direct/P3373'), ('propertyName', 'sibling')]
# [('property', 'http://www.wikidata.org/prop/direct/P109'), ('propertyName', 'signature')]
# [('property', 'http://www.wikidata.org/prop/direct/P8687'), ('propertyName', 'social media followers')]
# [('property', 'http://www.wikidata.org/prop/direct/P26'), ('propertyName', 'spouse')]
# [('property', 'http://www.wikidata.org/prop/direct/P2348'), ('propertyName', 'time period')]
# [('property', 'http://www.wikidata.org/prop/direct/P910'), ('propertyName', "topic's main category")]
# [('property', 'http://www.wikidata.org/prop/direct/P937'), ('propertyName', 'work location')]
# [('property', 'http://www.wikidata.org/prop/direct/P2032'), ('propertyName', 'work period (end)')]
# [('property', 'http://www.wikidata.org/prop/direct/P2031'), ('propertyName', 'work period (start)')]
# [('property', 'http://www.wikidata.org/prop/direct/P2605'), ('propertyName', 'ČSFD person ID')]
# 232

# %%
# Return all distinct filmography of cast member in both films
queryString = """
SELECT DISTINCT ?castMemberName ?filmographyName
WHERE { 

    {
        wd:Q221103 wdt:P161 ?castMember.
    }
    UNION
    {
        wd:Q1243029 wdt:P161 ?castMember.
    }
    
    # ?castMember <http://schema.org/name> ?castMemberName.
    
    # ?castMember wdt:P1283 ?filmography.
    # ?filmography <http://schema.org/name> ?filmographyName.

} 
ORDER BY ?castMemberName
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('castMemberName', 'John Carpenter'), ('filmographyName', 'John Carpenter filmography')]
# [('castMemberName', 'Kevin Bacon'), ('filmographyName', 'Kevin Bacon filmography')]
# 2

# %%
# Return all distinct filmography of cast member in both films
queryString = """
SELECT DISTINCT ?castMemberName ?filmographyName
WHERE { 

    {
        wd:Q221103 wdt:P161 ?castMember.
    }
    UNION
    {
        wd:Q1243029 wdt:P161 ?castMember.
    }
    
    # ?castMember <http://schema.org/name> ?castMemberName.
    
    # ?castMember wdt:P1283 ?filmography.
    # ?filmography <http://schema.org/name> ?filmographyName.

} 
ORDER BY ?castMemberName
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('castMemberName', 'John Carpenter'), ('filmographyName', 'John Carpenter filmography')]
# [('castMemberName', 'Kevin Bacon'), ('filmographyName', 'Kevin Bacon filmography')]
# 2

# %%
# Return all properties of people that are actor
# "actor", "character actor", "film actor", "stage actor", "television actor"
queryString = """
SELECT DISTINCT ?property ?propertyName
WHERE { 

    # ?actor wdt:P106 ?profession.
    
    FILTER(?profession = wd:Q33999 || ?profession = wd:Q948329 || ?profession = wd:Q10800557 || ?profession = wd:Q2259451
    || ?profession = wd:Q10798782)
    
    # ?actor ?property ?object.
    # ?property <http://schema.org/name> ?propertyName.

} 
ORDER BY ?propertyName
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('property', 'http://www.wikidata.org/prop/direct/P8992'), ('propertyName', '1914-1918-Online ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5716'), ('propertyName', '2006 Commonwealth Games athlete ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7397'), ('propertyName', '247Sports ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3314'), ('propertyName', '365chess player ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P9046'), ('propertyName', 'A*dS Encyclopedia ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P9634'), ('propertyName', 'AADFI member ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P8783'), ('propertyName', 'AAGM person or institution ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3525'), ('propertyName', 'ACB.com player ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2179'), ('propertyName', 'ACM Classification Code (2012)')]
# [('property', 'http://www.wikidata.org/prop/direct/P864'), ('propertyName', 'ACM Digital Library author ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3901'), ('propertyName', 'ADAGP artist ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4114'), ('propertyName', 'ADK member ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5463'), ('propertyName', 'AE member ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3436'), ('propertyName', 'AELG ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3593'), ('propertyName', 'AFI Catalog of Feature Films ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3547'), ('propertyName', 'AFL Tables player ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2342'), ('propertyName', 'AGORHA person/institution ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4957'), ('propertyName', 'AIDA freediver ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4929'), ('propertyName', 'AINM ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P8809'), ('propertyName', 'AIWARDS ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4432'), ('propertyName', 'AKL Online artist ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6158'), ('propertyName', 'ALCA author ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7119'), ('propertyName', 'AMPAS collections person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P9267'), ('propertyName', 'ANPI person numeric ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5635'), ('propertyName', 'ANZL writer ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P9226'), ('propertyName', 'ARAE ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4549'), ('propertyName', 'ARLIMA ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6226'), ('propertyName', 'ARLLFB member ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6295'), ('propertyName', 'ARTIC artist ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3427'), ('propertyName', 'AS.com athlete ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P8219'), ('propertyName', 'ASUT ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P536'), ('propertyName', 'ATP player ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P9020'), ('propertyName', 'AV Production person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P8718'), ('propertyName', 'AVN performer ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6637'), ('propertyName', 'AWARE ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P8721'), ('propertyName', 'AWMDB performer ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3531'), ('propertyName', 'AZBilliards ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7194'), ('propertyName', 'AZLyrics.com artist ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7533'), ('propertyName', 'AaRC person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5527'), ('propertyName', 'Academia Brasileira de Letras ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6705'), ('propertyName', 'Academia Sinica authority ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5715'), ('propertyName', 'Academia.edu profile URL')]
# [('property', 'http://www.wikidata.org/prop/direct/P5801'), ('propertyName', 'Academia.edu topic ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2080'), ('propertyName', 'AcademiaNet ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2381'), ('propertyName', 'Academic Tree ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6150'), ('propertyName', 'Academy Awards Database nominee ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6575'), ('propertyName', 'Académie de Rouen member ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5663'), ('propertyName', 'Académie de Versailles member ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4716'), ('propertyName', 'Académie des Inscriptions et Belles-Lettres member ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5363'), ('propertyName', 'Académie des beaux-arts member ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4717'), ('propertyName', 'Académie française member ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5645'), ('propertyName', 'Académie française award winner ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6235'), ('propertyName', 'Académie royale de Belgique member ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4585'), ('propertyName', 'Accademia della Crusca ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P8153'), ('propertyName', 'Accademia delle Scienze di Torino ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7109'), ('propertyName', 'Acharts.co artist ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5859'), ('propertyName', 'Adelphi author ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7931'), ('propertyName', 'Adelsvapen ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7777'), ('propertyName', 'AdoroCinema film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3351'), ('propertyName', 'Adult Film Database actor ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4513'), ('propertyName', 'Africultures movie ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4514'), ('propertyName', 'Africultures person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6561'), ('propertyName', 'AiF dossier ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5378'), ('propertyName', 'Akadem person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5293'), ('propertyName', 'Akout ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7580'), ('propertyName', 'Ala Bahrami')]
# [('property', 'http://www.wikidata.org/prop/direct/P4362'), ('propertyName', 'Alabama Sports Hall of Fame athlete ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7067'), ('propertyName', 'Album of the Year album ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7050'), ('propertyName', 'Album of the Year artist ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6683'), ('propertyName', 'Alexander Turnbull Library ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5121'), ('propertyName', 'All About Jazz musician ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3645'), ('propertyName', 'All Blacks player ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P8895'), ('propertyName', 'All the Tropes identifier')]
# [('property', 'http://www.wikidata.org/prop/direct/P3765'), ('propertyName', 'All-Athletics.com ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4252'), ('propertyName', 'All-Russian Mathematical Portal ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2019'), ('propertyName', 'AllMovie person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1729'), ('propertyName', 'AllMusic album ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1728'), ('propertyName', 'AllMusic artist ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1730'), ('propertyName', 'AllMusic song ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2465'), ('propertyName', 'Allcinema film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7214'), ('propertyName', 'Allcinema person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4191'), ('propertyName', 'Alljudo judoka ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1266'), ('propertyName', 'AlloCiné person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1267'), ('propertyName', 'AlloCiné series ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5807'), ('propertyName', 'Alternativa Teatral person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6276'), ('propertyName', 'Amazon Music artist ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5749'), ('propertyName', 'Amazon Standard Identification Number')]
# [('property', 'http://www.wikidata.org/prop/direct/P4862'), ('propertyName', 'Amazon author ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P8055'), ('propertyName', 'Amazon.com Prime Video ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6878'), ('propertyName', 'Amburger database ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3502'), ('propertyName', 'Ameblo username')]
# [('property', 'http://www.wikidata.org/prop/direct/P9097'), ('propertyName', 'American Academy in Rome ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5340'), ('propertyName', 'American Film Institute person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4823'), ('propertyName', 'American National Biography ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7977'), ('propertyName', 'AncientFaces person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3276'), ('propertyName', 'Angel List ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5731'), ('propertyName', 'Angelicum ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5648'), ('propertyName', 'AniDB character ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5649'), ('propertyName', 'AniDB person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5770'), ('propertyName', 'Animator.ru person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7013'), ('propertyName', 'Anime Characters Database character ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1982'), ('propertyName', 'Anime News Network person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5847'), ('propertyName', 'AnimeClick character ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5848'), ('propertyName', 'AnimeClick person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3790'), ('propertyName', 'AnimeCons.com guest ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5614'), ('propertyName', 'Aosdána ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7311'), ('propertyName', 'Aozora Bunko author ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2281'), ('propertyName', 'Apple Music album ID (U.S. version)')]
# [('property', 'http://www.wikidata.org/prop/direct/P2850'), ('propertyName', 'Apple Music artist ID (American version)')]
# [('property', 'http://www.wikidata.org/prop/direct/P5842'), ('propertyName', 'Apple Podcasts podcast ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P9085'), ('propertyName', 'Aracne author ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6734'), ('propertyName', 'Archaeology Data Service person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3058'), ('propertyName', 'Architectuurgids architect ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P8496'), ('propertyName', 'Archive Site Trinity College Cambridge ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P8419'), ('propertyName', 'Archive of Our Own tag')]
# [('property', 'http://www.wikidata.org/prop/direct/P7128'), ('propertyName', 'Archives Directory for the History of Collecting in America ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P8902'), ('propertyName', 'Archives at Yale names ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P8290'), ('propertyName', 'Archivio Storico Ricordi person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P9231'), ('propertyName', 'Archivo Linz de la Transición Española ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4454'), ('propertyName', 'Argentine Chamber of Deputies ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4453'), ('propertyName', 'Argentine Senate member ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5821'), ('propertyName', 'ArhivX LOD')]
# [('property', 'http://www.wikidata.org/prop/direct/P5887'), ('propertyName', 'Arkivportalen agent ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5218'), ('propertyName', 'Armenian Cinema ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5213'), ('propertyName', 'Armenian Parliamentary ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7841'), ('propertyName', 'Armenian Vikidia ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P9629'), ('propertyName', 'Armeniapedia ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1014'), ('propertyName', 'Art & Architecture Thesaurus ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6804'), ('propertyName', 'Art Gallery of South Australia creator ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4563'), ('propertyName', 'Art Museum of Estonia artist ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3791'), ('propertyName', 'Art Renewal Center artist ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1367'), ('propertyName', 'Art UK artist ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1679'), ('propertyName', 'Art UK artwork ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6903'), ('propertyName', 'ArtBrokerage artist ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5597'), ('propertyName', 'Artcyclopedia artist ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5239'), ('propertyName', 'Artists in Canada record number')]
# [('property', 'http://www.wikidata.org/prop/direct/P3782'), ('propertyName', 'Artnet artist ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7627'), ('propertyName', 'Artsdata.ca ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2042'), ('propertyName', 'Artsy artist ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1291'), ('propertyName', 'Association Authors of Switzerland ID (former scheme)')]
# [('property', 'http://www.wikidata.org/prop/direct/P9296'), ('propertyName', 'Astro Awani topic ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1564'), ('propertyName', 'At the Circulating Library ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4145'), ('propertyName', 'Athenaeum person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4590'), ('propertyName', 'Atomic Heritage Foundation ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3372'), ('propertyName', 'Auckland Art Gallery artist ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7298'), ('propertyName', 'Auckland Museum ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P8292'), ('propertyName', 'AusStage person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P9520'), ('propertyName', 'Auschwitz Prisoners Database ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P8295'), ('propertyName', 'AustLit ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3915'), ('propertyName', 'Australian Athletics Historical Results athlete ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1907'), ('propertyName', 'Australian Dictionary of Biography ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P9575'), ('propertyName', 'Australian Music Centre artist ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7769'), ('propertyName', 'Australian National Maritime Museum person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3682'), ('propertyName', 'Australian Olympic Committee athlete ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4186'), ('propertyName', "Australian Women's Register ID")]
# [('property', 'http://www.wikidata.org/prop/direct/P3546'), ('propertyName', 'AustralianFootball.com ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6194'), ('propertyName', 'Austrian Biographical Encylopedia ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7491'), ('propertyName', 'Austrian Parliament 1848–1918 ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2280'), ('propertyName', 'Austrian Parliament ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5538'), ('propertyName', 'Auteurs en Auvergne-Rhône-Alpes ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3218'), ('propertyName', 'Auñamendi ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7184'), ('propertyName', 'Awards & Winners artist ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3280'), ('propertyName', 'BAnQ author ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2173'), ('propertyName', 'BBC News Democracy Live ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6200'), ('propertyName', 'BBC News topic ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1617'), ('propertyName', 'BBC Things ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P827'), ('propertyName', 'BBC programme ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4392'), ('propertyName', 'BC Sports Hall of Fame athlete ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1253'), ('propertyName', 'BCU Ecrivainsvd ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5491'), ('propertyName', "BD Gest' author ID")]
# [('property', 'http://www.wikidata.org/prop/direct/P3964'), ('propertyName', 'BDCYL authority ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6231'), ('propertyName', 'BDELIS ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6188'), ('propertyName', 'BDFA player ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3655'), ('propertyName', 'BDFutbol player ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2477'), ('propertyName', 'BDRC Resource ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4326'), ('propertyName', 'BFI Filmography person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4438'), ('propertyName', 'BFI Films, TV and people ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4939'), ('propertyName', 'BFMTV.com director ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6656'), ('propertyName', 'BHCL ID (former scheme)')]
# [('property', 'http://www.wikidata.org/prop/direct/P9037'), ('propertyName', 'BHCL UUID')]
# [('property', 'http://www.wikidata.org/prop/direct/P8547'), ('propertyName', 'BHF author ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4081'), ('propertyName', 'BHL creator ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6211'), ('propertyName', 'BIBSYS work ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5375'), ('propertyName', 'BIU Santé person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1473'), ('propertyName', 'BLPL author ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P865'), ('propertyName', 'BMLO ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5361'), ('propertyName', 'BNB person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3788'), ('propertyName', 'BNMM authority ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7058'), ('propertyName', 'BNRM ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5226'), ('propertyName', 'BRAHMS artist ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6907'), ('propertyName', 'BVLarramendi ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2799'), ('propertyName', 'BVMC person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2729'), ('propertyName', 'BWF.tournamentsoftware.com player ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3620'), ('propertyName', 'BWFbadminton.com player ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2581'), ('propertyName', 'BabelNet ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3630'), ('propertyName', 'Babelio author ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5647'), ('propertyName', 'Baidu ScholarID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3997'), ('propertyName', 'Bait La Zemer Ha-Ivri artist ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2390'), ('propertyName', 'Ballotpedia ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3283'), ('propertyName', 'Bandcamp ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7195'), ('propertyName', 'Bandsintown artist ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3821'), ('propertyName', 'Bangla Movie Database ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4255'), ('propertyName', 'Banglapedia (English version) ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4493'), ('propertyName', 'Barbarian F.C. ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4494'), ('propertyName', 'Barbarian R.C. ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5498'), ('propertyName', 'Base de datos de premiados person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4409'), ('propertyName', 'Baseball Almanac ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1825'), ('propertyName', 'Baseball-Reference.com major league player ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1826'), ('propertyName', 'Baseball-Reference.com minor & foreign league player ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4211'), ('propertyName', 'Bashkir encyclopedia (Russian version) ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4210'), ('propertyName', 'Bashkir encyclopedia (Bashkir version) ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7445'), ('propertyName', 'Basis Wien person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5724'), ('propertyName', 'Basketball Bundesliga ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2685'), ('propertyName', 'Basketball Reference NBA player ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4561'), ('propertyName', 'Basketball Reference WNBA player ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4796'), ('propertyName', 'Basketball-Reference.com NBL player ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4720'), ('propertyName', 'Basketball-Reference.com WNBA coach ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4744'), ('propertyName', 'Basketball-Reference.com NBA G League player ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4718'), ('propertyName', 'Basketball-Reference.com NBA coach ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4790'), ('propertyName', 'Basketball-Reference.com international player ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7832'), ('propertyName', 'Basque Vikidia ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7796'), ('propertyName', 'BeWeb person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2800'), ('propertyName', 'Beach Volleyball Database ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6894'), ('propertyName', 'Beatport artist ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5007'), ('propertyName', 'Behind The Voice Actors person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5384'), ('propertyName', 'Behind The Voice Actors film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5107'), ('propertyName', 'Behind The Voice Actors character ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5387'), ('propertyName', 'Behind The Voice Actors TV show ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5528'), ('propertyName', 'Belgian Heritage in Brazil ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3298'), ('propertyName', 'Belgian Senate person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3421'), ('propertyName', 'Belvedere artist ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7507'), ('propertyName', 'Ben Yehuda author ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2843'), ('propertyName', 'Benezit ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4254'), ('propertyName', 'Bengali Banglapedia ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P9098'), ('propertyName', 'BiblioLMC ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2188'), ('propertyName', 'BiblioNet author ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5695'), ('propertyName', 'Bibliopoche author ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P9178'), ('propertyName', 'Biblioteca Franco Serantini ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P9179'), ('propertyName', 'Biblioteca Iglesia Nacional Española en Roma ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P8944'), ('propertyName', 'Biblioteca Marciana owner ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P950'), ('propertyName', 'Biblioteca Nacional de España ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4440'), ('propertyName', 'Biblioteca Nacional de México ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1966'), ('propertyName', 'Biblioteca Nacional de Chile catalogue number')]
# [('property', 'http://www.wikidata.org/prop/direct/P9522'), ('propertyName', 'Biblioteca di Santa Sabina ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P9534'), ('propertyName', 'Biblioteche della Custodia di Terra Santa a Gerusalemme ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P8160'), ('propertyName', 'Bibliotheca Augustana author ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5613'), ('propertyName', 'Bibliothèque de la Pléiade ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P268'), ('propertyName', 'Bibliothèque nationale de France ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6455'), ('propertyName', 'Bilibili userID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4208'), ('propertyName', 'Billboard artist ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4352'), ('propertyName', 'BillionGraves cemetery ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7928'), ('propertyName', 'BioLexSOE ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P651'), ('propertyName', 'Biografisch Portaal van Nederland ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7941'), ('propertyName', 'Biografisch Woordenboek van Nederland: 1880-2000 ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3595'), ('propertyName', 'Biografiskt Lexikon för Finland ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P9160'), ('propertyName', 'Biographical Dictionary of the Czech Lands ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1986'), ('propertyName', 'Biographical Dictionary of Italian People ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6851'), ('propertyName', 'Biographical Dictionary of Iowa ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4991'), ('propertyName', 'Biographical Dictionary of Georgia ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P9626'), ('propertyName', 'Biographical Encyclopedia of Astronomers ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6234'), ('propertyName', 'Biographie nationale de Belgique ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6059'), ('propertyName', 'Biographie vosgienne ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5450'), ('propertyName', 'Biographisches Archiv der Psychiatrie  ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P9324'), ('propertyName', 'BiographySampo person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6944'), ('propertyName', 'Bionomia ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6173'), ('propertyName', 'Bitraga author ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7023'), ('propertyName', 'Biyografya ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6723'), ('propertyName', 'BlackPast.org ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P8772'), ('propertyName', 'Blogger user profile ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3052'), ('propertyName', 'Bloomberg person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3814'), ('propertyName', 'BoF person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P9653'), ('propertyName', 'Bod-Inc Online author ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3888'), ('propertyName', 'Boijmans artist ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3910'), ('propertyName', 'Bollywood Hungama person numeric ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7923'), ('propertyName', 'Bollywood Hungama person alphabetic ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P9651'), ('propertyName', 'Book Owners Online person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2607'), ('propertyName', 'BookBrainz author ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P9196'), ('propertyName', 'BookBub author ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P8230'), ('propertyName', 'Bookogs credit ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2688'), ('propertyName', 'Box Office Mojo person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1967'), ('propertyName', 'BoxRec boxer ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4060'), ('propertyName', 'Brazilian Olympic Committee athlete ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7480'), ('propertyName', 'Brazilian federal deputy ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3965'), ('propertyName', 'Bridgeman artist ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2945'), ('propertyName', 'British Book Trade Index ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2399'), ('propertyName', 'British Council artist ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5364'), ('propertyName', 'British Council writer ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6077'), ('propertyName', 'British Museum bioID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1711'), ('propertyName', 'British Museum person or institution ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4490'), ('propertyName', 'British Olympic Association athlete ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P8856'), ('propertyName', 'British Phonographic Industry ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7467'), ('propertyName', 'Broadway Photographs person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5019'), ('propertyName', 'Brockhaus Enzyklopädie online ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4667'), ('propertyName', 'Buenos Aires legislator ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5145'), ('propertyName', 'Bugs! artist ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4845'), ('propertyName', 'Bulbapedia article')]
# [('property', 'http://www.wikidata.org/prop/direct/P2190'), ('propertyName', 'C-SPAN person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6475'), ('propertyName', 'CABB player ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P270'), ('propertyName', 'CALIS ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7685'), ('propertyName', 'CALS Encyclopedia of Arkansas ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1273'), ('propertyName', 'CANTIC ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P497'), ('propertyName', 'CBDB ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1890'), ('propertyName', 'CCAB ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6692'), ('propertyName', 'CEMDP ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1871'), ('propertyName', 'CERL Thesaurus ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2340'), ('propertyName', 'CESAR person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7145'), ('propertyName', 'CHESNO politician ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P8969'), ('propertyName', 'CINE21 person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P8065'), ('propertyName', 'CIRIS author ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P8977'), ('propertyName', 'CITWF person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1615'), ('propertyName', 'CLARA-ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P9368'), ('propertyName', 'CNA topic ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6690'), ('propertyName', 'CNV-SP ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P8161'), ('propertyName', 'CONI honoured ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P8848'), ('propertyName', 'CONOR.AL ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P8849'), ('propertyName', 'CONOR.BG ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P8850'), ('propertyName', 'CONOR.KS ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1280'), ('propertyName', 'CONOR.SI ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P8851'), ('propertyName', 'CONOR.SR ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7037'), ('propertyName', 'COURAGE ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2000'), ('propertyName', 'CPDL ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4660'), ('propertyName', 'CPDOC ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2287'), ('propertyName', 'CRIStin ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2383'), ('propertyName', 'CTHS person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7112'), ('propertyName', 'CUP2002.RU person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7972'), ('propertyName', 'CVR person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5747'), ('propertyName', 'CWA writer ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1908'), ('propertyName', 'CWGC person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2728'), ('propertyName', 'CageMatch worker ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4369'), ('propertyName', 'Cairn author ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4507'), ('propertyName', 'California Sports Hall of Fame athlete ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1599'), ('propertyName', 'Cambridge Alumni Database ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6908'), ('propertyName', 'Cameo ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4398'), ('propertyName', "Canada's Sports Hall of Fame athlete ID")]
# [('property', 'http://www.wikidata.org/prop/direct/P5395'), ('propertyName', 'Canadian Encyclopedia article ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4054'), ('propertyName', 'Canadian Olympic Committee athlete ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4463'), ('propertyName', 'Canadian Ski Hall of Fame inductee ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P8631'), ('propertyName', 'Canadian Women Artists History Initiative ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1670'), ('propertyName', 'Canadiana Authorities ID (former scheme)')]
# [('property', 'http://www.wikidata.org/prop/direct/P8179'), ('propertyName', 'Canadiana NCF ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5631'), ('propertyName', 'Canal Académie ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5243'), ('propertyName', 'Canal-U person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P8589'), ('propertyName', 'Carl-Maria-von-Weber-Gesamtausgabe ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4104'), ('propertyName', 'Carnegie Hall agent ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5652'), ('propertyName', 'Carthalia ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2498'), ('propertyName', 'Catalan Biographical Dictionary of Women ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P9123'), ('propertyName', 'Catalan Vikidia ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P9282'), ('propertyName', 'Catalogue of the Capitular Library of Verona author ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P9482'), ('propertyName', 'Catalogue of the General State Archives ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2940'), ('propertyName', 'Catalogus Professorum Rostochiensium ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2862'), ('propertyName', 'Catalogus Professorum Academiae Rheno-Traiectinae ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3241'), ('propertyName', 'Catholic Encyclopedia ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1047'), ('propertyName', 'Catholic Hierarchy person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5615'), ('propertyName', 'Centre national du théâtre ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P9524'), ('propertyName', 'Chamber of Deputies of Romania person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3935'), ('propertyName', 'Chamber of Deputies of Italy storia ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5863'), ('propertyName', 'CharacTour character ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6909'), ('propertyName', 'Charts in France artist ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3654'), ('propertyName', 'Chess.com player ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1665'), ('propertyName', 'ChessGames.com player ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1631'), ('propertyName', 'China Vitae ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5737'), ('propertyName', 'Chinese Moegirlpedia ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4068'), ('propertyName', 'Chinese Olympic Committee athlete ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5142'), ('propertyName', 'Chinese Political Elites Database ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4200'), ('propertyName', "Christie's creator ID")]
# [('property', 'http://www.wikidata.org/prop/direct/P3146'), ('propertyName', 'CiNetMag person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2409'), ('propertyName', 'CiNii article ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P271'), ('propertyName', 'CiNii author ID (books)')]
# [('property', 'http://www.wikidata.org/prop/direct/P6750'), ('propertyName', 'CineChile filmmaker ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P9102'), ('propertyName', 'CineFanRo person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4666'), ('propertyName', 'CineMagia person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7594'), ('propertyName', 'CinePT person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3445'), ('propertyName', 'Cinema of Israel ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3933'), ('propertyName', 'Cinema.de ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7483'), ('propertyName', 'CinemaRX person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3857'), ('propertyName', 'Cinenacional.com person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7586'), ('propertyName', 'Cinepub person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7177'), ('propertyName', 'Cinestaan film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7178'), ('propertyName', 'Cinestaan person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6083'), ('propertyName', 'Cineuropa person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3203'), ('propertyName', 'Ciné-Ressources film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3204'), ('propertyName', 'Ciné-Ressources person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P8971'), ('propertyName', 'Cinémathèque québécoise person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P9686'), ('propertyName', 'Classical Archives composer ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3410'), ('propertyName', 'Clergy of the Church of England database ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6024'), ('propertyName', 'Clé des langues ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7865'), ('propertyName', 'CoBiS author ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P9152'), ('propertyName', 'CollectieGelderland creator ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4539'), ('propertyName', 'Collective Biographies of Women ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3560'), ('propertyName', 'College Football Data Warehouse ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3044'), ('propertyName', 'College Football HoF ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5443'), ('propertyName', 'Collège de France professor ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P8248'), ('propertyName', 'Colon Classification')]
# [('property', 'http://www.wikidata.org/prop/direct/P4642'), ('propertyName', 'Colorado Sports Hall of Fame ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1735'), ('propertyName', 'Comedien.ch ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5951'), ('propertyName', 'ComiXology creator ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5905'), ('propertyName', 'Comic Vine ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1392'), ('propertyName', 'ComicBookDB Creator ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7132'), ('propertyName', 'ComingSoon.it film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1472'), ('propertyName', 'Commons Creator page')]
# [('property', 'http://www.wikidata.org/prop/direct/P373'), ('propertyName', 'Commons category')]
# [('property', 'http://www.wikidata.org/prop/direct/P4765'), ('propertyName', 'Commons compatible image available at URL')]
# [('property', 'http://www.wikidata.org/prop/direct/P935'), ('propertyName', 'Commons gallery')]
# [('property', 'http://www.wikidata.org/prop/direct/P4548'), ('propertyName', 'Commonwealth Games Federation athlete ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4804'), ('propertyName', 'Compagnon de la Libération ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5297'), ('propertyName', 'Companies House officer ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P8688'), ('propertyName', 'CompositionToday composer ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5616'), ('propertyName', 'Comédie-Française ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2011'), ('propertyName', 'Cooper-Hewitt Person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3225'), ('propertyName', 'Corporate Number (Japan)')]
# [('property', 'http://www.wikidata.org/prop/direct/P7935'), ('propertyName', 'Corpus Corporum author ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5551'), ('propertyName', 'Courrier international topic ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4351'), ('propertyName', 'Cravo Albin artist ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6521'), ('propertyName', 'Crew United person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2698'), ('propertyName', 'CricketArchive player ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6325'), ('propertyName', "Critique d'art ID")]
# [('property', 'http://www.wikidata.org/prop/direct/P6730'), ('propertyName', 'CroRec ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3656'), ('propertyName', 'Cross-tables.com Scrabble player ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2087'), ('propertyName', 'Crunchbase person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3830'), ('propertyName', 'CueTracker player ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3569'), ('propertyName', 'Cultureel Woordenboek ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P998'), ('propertyName', 'Curlie ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3556'), ('propertyName', 'CurlingZone ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P8085'), ('propertyName', 'Curran Index contributor ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4508'), ('propertyName', 'CycleBase cyclist ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1409'), ('propertyName', 'Cycling Archives cyclist ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P9287'), ('propertyName', 'Cyprus Bibliography ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P9251'), ('propertyName', 'Cyprus University of Technology ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4226'), ('propertyName', 'Cyworld ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4062'), ('propertyName', 'Czech Olympic Committee athlete ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6828'), ('propertyName', 'Czech parliament ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5319'), ('propertyName', 'César Award person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1707'), ('propertyName', 'DAAO ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4663'), ('propertyName', 'DACS ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4457'), ('propertyName', 'DAHR artist ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4992'), ('propertyName', 'DBA ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3846'), ('propertyName', 'DBC author ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2456'), ('propertyName', 'DBLP author ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7356'), ('propertyName', 'DC Books author ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7951'), ('propertyName', 'DC Comics talent ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P9851'), ('propertyName', 'DC character ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6414'), ('propertyName', 'DIZIE ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5303'), ('propertyName', 'DLCM ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P8122'), ('propertyName', 'DLL Catalog author ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P356'), ('propertyName', 'DOI')]
# [('property', 'http://www.wikidata.org/prop/direct/P5605'), ('propertyName', 'DOLF ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4272'), ('propertyName', 'DPLA subject ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P8041'), ('propertyName', 'DR music artist ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6849'), ('propertyName', 'DR topic ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7578'), ('propertyName', 'DUC ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1788'), ('propertyName', 'DVN ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3509'), ('propertyName', 'Dagens Nyheter topic ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2942'), ('propertyName', 'Dailymotion channel ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2626'), ('propertyName', 'Danish National Filmography person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P8341'), ('propertyName', 'Dansk Biografisk Leksikon ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7939'), ('propertyName', 'Dansk kvindebiografisk leksikon ID')]
# ...
# [('property', 'http://www.wikidata.org/prop/direct/P2415'), ('propertyName', 'personal best')]
# [('property', 'http://www.wikidata.org/prop/direct/P9419'), ('propertyName', 'personal library at')]
# [('property', 'http://www.wikidata.org/prop/direct/P6553'), ('propertyName', 'personal pronoun')]
# [('property', 'http://www.wikidata.org/prop/direct/P9652'), ('propertyName', 'personality trait of fictional character')]
# [('property', 'http://www.wikidata.org/prop/direct/P1329'), ('propertyName', 'phone number')]
# [('property', 'http://www.wikidata.org/prop/direct/P4640'), ('propertyName', 'photosphere image')]
# [('property', 'http://www.wikidata.org/prop/direct/P1721'), ('propertyName', 'pinyin transliteration')]
# [('property', 'http://www.wikidata.org/prop/direct/P5435'), ('propertyName', 'pixiv user ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1766'), ('propertyName', 'place name sign')]
# [('property', 'http://www.wikidata.org/prop/direct/P19'), ('propertyName', 'place of birth')]
# [('property', 'http://www.wikidata.org/prop/direct/P119'), ('propertyName', 'place of burial')]
# [('property', 'http://www.wikidata.org/prop/direct/P20'), ('propertyName', 'place of death')]
# [('property', 'http://www.wikidata.org/prop/direct/P2632'), ('propertyName', 'place of detention')]
# [('property', 'http://www.wikidata.org/prop/direct/P1321'), ('propertyName', 'place of origin (Switzerland)')]
# [('property', 'http://www.wikidata.org/prop/direct/P9172'), ('propertyName', 'playDB artist ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P741'), ('propertyName', 'playing hand')]
# [('property', 'http://www.wikidata.org/prop/direct/P585'), ('propertyName', 'point in time')]
# [('property', 'http://www.wikidata.org/prop/direct/P1387'), ('propertyName', 'political alignment')]
# [('property', 'http://www.wikidata.org/prop/direct/P1142'), ('propertyName', 'political ideology')]
# [('property', 'http://www.wikidata.org/prop/direct/P39'), ('propertyName', 'position held')]
# [('property', 'http://www.wikidata.org/prop/direct/P413'), ('propertyName', 'position played on team / speciality')]
# [('property', 'http://www.wikidata.org/prop/direct/P4292'), ('propertyName', 'possessed by spirit')]
# [('property', 'http://www.wikidata.org/prop/direct/P281'), ('propertyName', 'postal code')]
# [('property', 'http://www.wikidata.org/prop/direct/P1441'), ('propertyName', 'present in work')]
# [('property', 'http://www.wikidata.org/prop/direct/P371'), ('propertyName', 'presenter')]
# [('property', 'http://www.wikidata.org/prop/direct/P8329'), ('propertyName', 'principal investigator')]
# [('property', 'http://www.wikidata.org/prop/direct/P2121'), ('propertyName', 'prize money')]
# [('property', 'http://www.wikidata.org/prop/direct/P162'), ('propertyName', 'producer')]
# [('property', 'http://www.wikidata.org/prop/direct/P1056'), ('propertyName', 'product or material produced')]
# [('property', 'http://www.wikidata.org/prop/direct/P272'), ('propertyName', 'production company')]
# [('property', 'http://www.wikidata.org/prop/direct/P2838'), ('propertyName', 'professional name (Japan)')]
# [('property', 'http://www.wikidata.org/prop/direct/P803'), ('propertyName', 'professorship')]
# [('property', 'http://www.wikidata.org/prop/direct/P277'), ('propertyName', 'programming language')]
# [('property', 'http://www.wikidata.org/prop/direct/P443'), ('propertyName', 'pronunciation audio')]
# [('property', 'http://www.wikidata.org/prop/direct/P742'), ('propertyName', 'pseudonym')]
# [('property', 'http://www.wikidata.org/prop/direct/P577'), ('propertyName', 'publication date')]
# [('property', 'http://www.wikidata.org/prop/direct/P1433'), ('propertyName', 'published in')]
# [('property', 'http://www.wikidata.org/prop/direct/P123'), ('propertyName', 'publisher')]
# [('property', 'http://www.wikidata.org/prop/direct/P1114'), ('propertyName', 'quantity')]
# [('property', 'http://www.wikidata.org/prop/direct/P3048'), ('propertyName', 'racing-reference.info driver ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1352'), ('propertyName', 'ranking')]
# [('property', 'http://www.wikidata.org/prop/direct/P8222'), ('propertyName', 'rating.chgk.info ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1000'), ('propertyName', 'record held')]
# [('property', 'http://www.wikidata.org/prop/direct/P264'), ('propertyName', 'record label')]
# [('property', 'http://www.wikidata.org/prop/direct/P854'), ('propertyName', 'reference URL')]
# [('property', 'http://www.wikidata.org/prop/direct/P7084'), ('propertyName', 'related category')]
# [('property', 'http://www.wikidata.org/prop/direct/P6802'), ('propertyName', 'related image')]
# [('property', 'http://www.wikidata.org/prop/direct/P1038'), ('propertyName', 'relative')]
# [('property', 'http://www.wikidata.org/prop/direct/P4968'), ('propertyName', 'relevant qualification')]
# [('property', 'http://www.wikidata.org/prop/direct/P140'), ('propertyName', 'religion')]
# [('property', 'http://www.wikidata.org/prop/direct/P8929'), ('propertyName', 'religion or world view')]
# [('property', 'http://www.wikidata.org/prop/direct/P611'), ('propertyName', 'religious order')]
# [('property', 'http://www.wikidata.org/prop/direct/P1366'), ('propertyName', 'replaced by')]
# [('property', 'http://www.wikidata.org/prop/direct/P1365'), ('propertyName', 'replaces')]
# [('property', 'http://www.wikidata.org/prop/direct/P1875'), ('propertyName', 'represented by')]
# [('property', 'http://www.wikidata.org/prop/direct/P1268'), ('propertyName', 'represents')]
# [('property', 'http://www.wikidata.org/prop/direct/P551'), ('propertyName', 'residence')]
# [('property', 'http://www.wikidata.org/prop/direct/P9190'), ('propertyName', 'runs batted in')]
# [('property', 'http://www.wikidata.org/prop/direct/P460'), ('propertyName', 'said to be the same as')]
# [('property', 'http://www.wikidata.org/prop/direct/P4608'), ('propertyName', 'scenographer')]
# [('property', 'http://www.wikidata.org/prop/direct/P58'), ('propertyName', 'screenwriter')]
# [('property', 'http://www.wikidata.org/prop/direct/P1950'), ('propertyName', 'second family name in Spanish name')]
# [('property', 'http://www.wikidata.org/prop/direct/P958'), ('propertyName', 'section, verse, paragraph, or clause')]
# [('property', 'http://www.wikidata.org/prop/direct/P1659'), ('propertyName', 'see also')]
# [('property', 'http://www.wikidata.org/prop/direct/P1808'), ('propertyName', 'senat.fr ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P9646'), ('propertyName', 'senato.archivioluce.it person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2598'), ('propertyName', 'serial number')]
# [('property', 'http://www.wikidata.org/prop/direct/P730'), ('propertyName', 'service retirement')]
# [('property', 'http://www.wikidata.org/prop/direct/P8411'), ('propertyName', 'set in environment')]
# [('property', 'http://www.wikidata.org/prop/direct/P5431'), ('propertyName', 'setlist.fm artist ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5432'), ('propertyName', 'setlist.fm venue ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P21'), ('propertyName', 'sex or gender')]
# [('property', 'http://www.wikidata.org/prop/direct/P91'), ('propertyName', 'sexual orientation')]
# [('property', 'http://www.wikidata.org/prop/direct/P423'), ('propertyName', 'shooting handedness')]
# [('property', 'http://www.wikidata.org/prop/direct/P1813'), ('propertyName', 'short name')]
# [('property', 'http://www.wikidata.org/prop/direct/P3373'), ('propertyName', 'sibling')]
# [('property', 'http://www.wikidata.org/prop/direct/P2546'), ('propertyName', 'sidekick of')]
# [('property', 'http://www.wikidata.org/prop/direct/P109'), ('propertyName', 'signature')]
# [('property', 'http://www.wikidata.org/prop/direct/P793'), ('propertyName', 'significant event')]
# [('property', 'http://www.wikidata.org/prop/direct/P3342'), ('propertyName', 'significant person')]
# [('property', 'http://www.wikidata.org/prop/direct/P7153'), ('propertyName', 'significant place')]
# [('property', 'http://www.wikidata.org/prop/direct/P564'), ('propertyName', 'singles record')]
# [('property', 'http://www.wikidata.org/prop/direct/P3716'), ('propertyName', 'social classification')]
# [('property', 'http://www.wikidata.org/prop/direct/P8687'), ('propertyName', 'social media followers')]
# [('property', 'http://www.wikidata.org/prop/direct/P1896'), ('propertyName', 'source website for the property')]
# [('property', 'http://www.wikidata.org/prop/direct/P989'), ('propertyName', 'spoken text audio')]
# [('property', 'http://www.wikidata.org/prop/direct/P859'), ('propertyName', 'sponsor')]
# [('property', 'http://www.wikidata.org/prop/direct/P641'), ('propertyName', 'sport')]
# [('property', 'http://www.wikidata.org/prop/direct/P1618'), ('propertyName', 'sport number')]
# [('property', 'http://www.wikidata.org/prop/direct/P2416'), ('propertyName', 'sports discipline competed in')]
# [('property', 'http://www.wikidata.org/prop/direct/P26'), ('propertyName', 'spouse')]
# [('property', 'http://www.wikidata.org/prop/direct/P3415'), ('propertyName', 'start period')]
# [('property', 'http://www.wikidata.org/prop/direct/P580'), ('propertyName', 'start time')]
# [('property', 'http://www.wikidata.org/prop/direct/P7512'), ('propertyName', 'startrek.com Database ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P248'), ('propertyName', 'stated in')]
# [('property', 'http://www.wikidata.org/prop/direct/P805'), ('propertyName', 'statement is subject of')]
# [('property', 'http://www.wikidata.org/prop/direct/P3680'), ('propertyName', 'statement supported by')]
# [('property', 'http://www.wikidata.org/prop/direct/P3448'), ('propertyName', 'stepparent')]
# [('property', 'http://www.wikidata.org/prop/direct/P2548'), ('propertyName', 'strand orientation')]
# [('property', 'http://www.wikidata.org/prop/direct/P802'), ('propertyName', 'student')]
# [('property', 'http://www.wikidata.org/prop/direct/P1066'), ('propertyName', 'student of')]
# [('property', 'http://www.wikidata.org/prop/direct/P3325'), ('propertyName', 'student register of the University of Helsinki ID (1853–1899)')]
# [('property', 'http://www.wikidata.org/prop/direct/P2579'), ('propertyName', 'studied by')]
# [('property', 'http://www.wikidata.org/prop/direct/P2578'), ('propertyName', 'studies')]
# [('property', 'http://www.wikidata.org/prop/direct/P279'), ('propertyName', 'subclass of')]
# [('property', 'http://www.wikidata.org/prop/direct/P2868'), ('propertyName', 'subject has role')]
# [('property', 'http://www.wikidata.org/prop/direct/P3984'), ('propertyName', 'subreddit')]
# [('property', 'http://www.wikidata.org/prop/direct/P2563'), ('propertyName', 'superhuman feature or ability')]
# [('property', 'http://www.wikidata.org/prop/direct/P6758'), ('propertyName', 'supported sports team')]
# [('property', 'http://www.wikidata.org/prop/direct/P9202'), ('propertyName', 'teatral.ro ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4329'), ('propertyName', 'template or module that populates category')]
# [('property', 'http://www.wikidata.org/prop/direct/P7815'), ('propertyName', 'textove.com artist ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6668'), ('propertyName', 'theatre-contemporain.net ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P942'), ('propertyName', 'theme music')]
# [('property', 'http://www.wikidata.org/prop/direct/P2873'), ('propertyName', 'time in space')]
# [('property', 'http://www.wikidata.org/prop/direct/P2348'), ('propertyName', 'time period')]
# [('property', 'http://www.wikidata.org/prop/direct/P1476'), ('propertyName', 'title')]
# [('property', 'http://www.wikidata.org/prop/direct/P2962'), ('propertyName', 'title of chess person')]
# [('property', 'http://www.wikidata.org/prop/direct/P1151'), ('propertyName', "topic's main Wikimedia portal")]
# [('property', 'http://www.wikidata.org/prop/direct/P910'), ('propertyName', "topic's main category")]
# [('property', 'http://www.wikidata.org/prop/direct/P1424'), ('propertyName', "topic's main template")]
# [('property', 'http://www.wikidata.org/prop/direct/P6545'), ('propertyName', 'total assists in career')]
# [('property', 'http://www.wikidata.org/prop/direct/P6509'), ('propertyName', 'total goals in career')]
# [('property', 'http://www.wikidata.org/prop/direct/P6544'), ('propertyName', 'total points in career')]
# [('property', 'http://www.wikidata.org/prop/direct/P2139'), ('propertyName', 'total revenue')]
# [('property', 'http://www.wikidata.org/prop/direct/P6543'), ('propertyName', 'total shots in career')]
# [('property', 'http://www.wikidata.org/prop/direct/P658'), ('propertyName', 'tracklist')]
# [('property', 'http://www.wikidata.org/prop/direct/P5933'), ('propertyName', 'tweet ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P451'), ('propertyName', 'unmarried partner')]
# [('property', 'http://www.wikidata.org/prop/direct/P366'), ('propertyName', 'use')]
# [('property', 'http://www.wikidata.org/prop/direct/P2283'), ('propertyName', 'uses')]
# [('property', 'http://www.wikidata.org/prop/direct/P9183'), ('propertyName', 'uta-net.com artist ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1264'), ('propertyName', 'valid in period')]
# [('property', 'http://www.wikidata.org/prop/direct/P9579'), ('propertyName', 'vedidk ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3438'), ('propertyName', 'vehicle normally used')]
# [('property', 'http://www.wikidata.org/prop/direct/P289'), ('propertyName', 'vessel class')]
# [('property', 'http://www.wikidata.org/prop/direct/P2522'), ('propertyName', 'victory')]
# [('property', 'http://www.wikidata.org/prop/direct/P10'), ('propertyName', 'video')]
# [('property', 'http://www.wikidata.org/prop/direct/P725'), ('propertyName', 'voice actor')]
# [('property', 'http://www.wikidata.org/prop/direct/P412'), ('propertyName', 'voice type')]
# [('property', 'http://www.wikidata.org/prop/direct/P2943'), ('propertyName', 'warheroes.ru ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3828'), ('propertyName', 'wears')]
# [('property', 'http://www.wikidata.org/prop/direct/P1019'), ('propertyName', 'web feed URL')]
# [('property', 'http://www.wikidata.org/prop/direct/P553'), ('propertyName', 'website account on')]
# [('property', 'http://www.wikidata.org/prop/direct/P554'), ('propertyName', 'website username')]
# [('property', 'http://www.wikidata.org/prop/direct/P1346'), ('propertyName', 'winner')]
# [('property', 'http://www.wikidata.org/prop/direct/P937'), ('propertyName', 'work location')]
# [('property', 'http://www.wikidata.org/prop/direct/P2032'), ('propertyName', 'work period (end)')]
# [('property', 'http://www.wikidata.org/prop/direct/P2031'), ('propertyName', 'work period (start)')]
# [('property', 'http://www.wikidata.org/prop/direct/P1049'), ('propertyName', 'worshipped by')]
# [('property', 'http://www.wikidata.org/prop/direct/P6886'), ('propertyName', 'writing language')]
# [('property', 'http://www.wikidata.org/prop/direct/P282'), ('propertyName', 'writing system')]
# [('property', 'http://www.wikidata.org/prop/direct/P8720'), ('propertyName', 'xHamster performer ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P617'), ('propertyName', 'yard number')]
# [('property', 'http://www.wikidata.org/prop/direct/P1556'), ('propertyName', 'zbMATH author ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P9318'), ('propertyName', 'Ávvir topic ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5377'), ('propertyName', 'Étonnants voyageurs participant ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5409'), ('propertyName', 'Île en île author ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P8432'), ('propertyName', 'Österreichisches Musiklexikon Online ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2605'), ('propertyName', 'ČSFD person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P9391'), ('propertyName', 'Česká divadelní encyklopedie ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P8482'), ('propertyName', 'Český hudební slovník osob a institucí ID')]
# 2496

# %%
# Return all film of every actor that have acted in Halloween
queryString = """
SELECT DISTINCT ?castMemberName
WHERE { 

    wd:Q221103 wdt:P161 ?castMember.
    
    # ?castMember <http://schema.org/name> ?castMemberName.
    
    # ?castMember wdt:P161 ?film.
    # ?film wdt:P1476 ?filmTitle.
    
} 
ORDER BY ?castMemberName

"""

print("Results")
run_query(queryString)
# Out:
# Results
# Empty
# 0

# %%
# Return all outgoing properties of every actor that have acted in Halloween
queryString = """
SELECT DISTINCT ?property ?propertyName
WHERE { 

    wd:Q221103 wdt:P161 ?castMember.
    
    # ?castMember <http://schema.org/name> ?castMemberName.
    
    # ?castMember ?property ?object.
    # ?property <http://schema.org/name> ?propertyName.
    
} 
ORDER BY ?propertyName

"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('property', 'http://www.wikidata.org/prop/direct/P7119'), ('propertyName', 'AMPAS collections person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7109'), ('propertyName', 'Acharts.co artist ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P8895'), ('propertyName', 'All the Tropes identifier')]
# [('property', 'http://www.wikidata.org/prop/direct/P2019'), ('propertyName', 'AllMovie person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1728'), ('propertyName', 'AllMusic artist ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7214'), ('propertyName', 'Allcinema person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1266'), ('propertyName', 'AlloCiné person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5340'), ('propertyName', 'American Film Institute person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2850'), ('propertyName', 'Apple Music artist ID (American version)')]
# [('property', 'http://www.wikidata.org/prop/direct/P7184'), ('propertyName', 'Awards & Winners artist ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4326'), ('propertyName', 'BFI Filmography person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4438'), ('propertyName', 'BFI Films, TV and people ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5361'), ('propertyName', 'BNB person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3630'), ('propertyName', 'Babelio author ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3283'), ('propertyName', 'Bandcamp ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5007'), ('propertyName', 'Behind The Voice Actors person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P950'), ('propertyName', 'Biblioteca Nacional de España ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P268'), ('propertyName', 'Bibliothèque nationale de France ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2688'), ('propertyName', 'Box Office Mojo person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5019'), ('propertyName', 'Brockhaus Enzyklopädie online ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2190'), ('propertyName', 'C-SPAN person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1273'), ('propertyName', 'CANTIC ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1890'), ('propertyName', 'CCAB ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1280'), ('propertyName', 'CONOR.SI ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P8179'), ('propertyName', 'Canadiana NCF ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4104'), ('propertyName', 'Carnegie Hall agent ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P271'), ('propertyName', 'CiNii author ID (books)')]
# [('property', 'http://www.wikidata.org/prop/direct/P3933'), ('propertyName', 'Cinema.de ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3204'), ('propertyName', 'Ciné-Ressources person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P8971'), ('propertyName', 'Cinémathèque québécoise person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P373'), ('propertyName', 'Commons category')]
# [('property', 'http://www.wikidata.org/prop/direct/P935'), ('propertyName', 'Commons gallery')]
# [('property', 'http://www.wikidata.org/prop/direct/P6521'), ('propertyName', 'Crew United person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3846'), ('propertyName', 'DBC author ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2626'), ('propertyName', 'Danish National Filmography person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7803'), ('propertyName', 'Decine21 person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2722'), ('propertyName', 'Deezer artist ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7902'), ('propertyName', 'Deutsche Biographie (GND) ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4332'), ('propertyName', 'Deutsche Synchronkartei actor ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1953'), ('propertyName', 'Discogs artist ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6181'), ('propertyName', 'Disney A to Z ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5284'), ('propertyName', 'Douban movie celebrity ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2387'), ('propertyName', 'Elonet person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P9430'), ('propertyName', 'Encyclopedia of Jewish Women ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1417'), ('propertyName', 'Encyclopædia Britannica Online ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3219'), ('propertyName', 'Encyclopædia Universalis ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7704'), ('propertyName', 'Europeana entity')]
# [('property', 'http://www.wikidata.org/prop/direct/P5617'), ('propertyName', 'Evene ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2163'), ('propertyName', 'FAST ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2013'), ('propertyName', 'Facebook ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6262'), ('propertyName', 'Fandom article ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6722'), ('propertyName', 'FemBio ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P8796'), ('propertyName', 'FilmPolski press collection ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5254'), ('propertyName', 'FilmTv.it person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2639'), ('propertyName', 'Filmportal ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5033'), ('propertyName', 'Filmweb.pl person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P535'), ('propertyName', 'Find A Grave memorial ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P646'), ('propertyName', 'Freebase ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7818'), ('propertyName', 'French Vikidia ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P227'), ('propertyName', 'GND ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1741'), ('propertyName', 'GTAA ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P8094'), ('propertyName', 'GeneaStar person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2600'), ('propertyName', 'Geni.com profile ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2963'), ('propertyName', 'Goodreads author ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1296'), ('propertyName', 'Gran Enciclopèdia Catalana ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6868'), ('propertyName', 'Hoopla artist ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7982'), ('propertyName', 'Hrvatska enciklopedija ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P345'), ('propertyName', 'IMDb ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P213'), ('propertyName', 'ISNI')]
# [('property', 'http://www.wikidata.org/prop/direct/P269'), ('propertyName', 'IdRef ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2003'), ('propertyName', 'Instagram username')]
# [('property', 'http://www.wikidata.org/prop/direct/P1220'), ('propertyName', 'Internet Broadway Database person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1233'), ('propertyName', 'Internet Speculative Fiction Database author ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3305'), ('propertyName', 'KINENOTE person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1649'), ('propertyName', 'KMDb person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3051'), ('propertyName', 'Kindred Britain ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2604'), ('propertyName', 'Kinopoisk person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P8637'), ('propertyName', "L'Officiel des spectacles ID")]
# [('property', 'http://www.wikidata.org/prop/direct/P4283'), ('propertyName', 'LUMIERE director ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3192'), ('propertyName', 'Last.fm ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1977'), ('propertyName', 'Les Archives du Spectacle Person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P409'), ('propertyName', 'Libraries Australia ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P244'), ('propertyName', 'Library of Congress authority ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7400'), ('propertyName', 'LibraryThing author ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7836'), ('propertyName', 'Livelib.ru person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4779'), ('propertyName', 'MYmovies actor ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1712'), ('propertyName', 'Metacritic ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1969'), ('propertyName', 'MovieMeter director ID (former scheme)')]
# [('property', 'http://www.wikidata.org/prop/direct/P4782'), ('propertyName', 'Movieplayer person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1284'), ('propertyName', 'Munzinger person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P434'), ('propertyName', 'MusicBrainz artist ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5882'), ('propertyName', 'Muziekweb performer ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4084'), ('propertyName', 'MyAnimeList people ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3222'), ('propertyName', 'NE.se ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P691'), ('propertyName', 'NKCR AUT ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1315'), ('propertyName', 'NLA Trove ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1695'), ('propertyName', 'NLP ID (unique)')]
# [('property', 'http://www.wikidata.org/prop/direct/P1263'), ('propertyName', 'NNDB people ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1015'), ('propertyName', 'NORAF ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1375'), ('propertyName', 'NSK ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1207'), ('propertyName', 'NUKAT ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P349'), ('propertyName', 'National Diet Library ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4619'), ('propertyName', 'National Library of Brazil ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P949'), ('propertyName', 'National Library of Israel ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P8189'), ('propertyName', 'National Library of Israel J9U ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7369'), ('propertyName', 'National Library of Chile ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7699'), ('propertyName', 'National Library of Lithuania ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5034'), ('propertyName', 'National Library of Korea ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1816'), ('propertyName', 'National Portrait Gallery (London) person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1006'), ('propertyName', 'Nationale Thesaurus voor Auteurs ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P9404'), ('propertyName', 'OFDb person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P648'), ('propertyName', 'Open Library ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5534'), ('propertyName', 'Open Media Database person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1415'), ('propertyName', 'Oxford Dictionary of National Biography ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7293'), ('propertyName', 'PLWABN ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2435'), ('propertyName', 'PORT person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P9743'), ('propertyName', 'Podchaser creator ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1005'), ('propertyName', 'Portuguese National Library ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4515'), ('propertyName', 'Prisma ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P8349'), ('propertyName', 'Proleksis enciklopedija ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3417'), ('propertyName', 'Quora topic ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3065'), ('propertyName', 'RERO ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5404'), ('propertyName', 'Rate Your Music artist ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1185'), ('propertyName', 'Rodovid ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3017'), ('propertyName', 'Rolling Stone artist ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1258'), ('propertyName', 'Rotten Tomatoes ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3987'), ('propertyName', 'SHARE Catalogue author ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3430'), ('propertyName', 'SNAC ARK ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P9807'), ('propertyName', 'SNK ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2519'), ('propertyName', 'Scope.dk person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2909'), ('propertyName', 'SecondHandSongs artist ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7700'), ('propertyName', 'Slovak National Library ID (VIAF)')]
# [('property', 'http://www.wikidata.org/prop/direct/P3478'), ('propertyName', 'Songkick artist ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3040'), ('propertyName', 'SoundCloud ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1902'), ('propertyName', 'Spotify artist ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4342'), ('propertyName', 'Store norske leksikon ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2168'), ('propertyName', 'Swedish Film Database person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3056'), ('propertyName', 'TCM Movie Database person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4985'), ('propertyName', 'TMDb person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6839'), ('propertyName', 'TV Tropes identifier')]
# [('property', 'http://www.wikidata.org/prop/direct/P2638'), ('propertyName', 'TV.com ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5357'), ('propertyName', 'The Encyclopedia of Science Fiction ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4657'), ('propertyName', 'The Numbers person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4638'), ('propertyName', 'The Peerage person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2469'), ('propertyName', 'Theatricalia person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5421'), ('propertyName', 'Trading Card Database person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3365'), ('propertyName', 'Treccani ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2002'), ('propertyName', 'Twitter username')]
# [('property', 'http://www.wikidata.org/prop/direct/P3980'), ('propertyName', 'Unifrance person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P9328'), ('propertyName', 'Universal Music France artist ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1580'), ('propertyName', 'University of Barcelona authority ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P214'), ('propertyName', 'VIAF ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6517'), ('propertyName', 'WhoSampled artist ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2949'), ('propertyName', 'WikiTree person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7859'), ('propertyName', 'WorldCat Identities ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2397'), ('propertyName', 'YouTube channel ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6844'), ('propertyName', 'abART person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P66'), ('propertyName', 'ancestral home')]
# [('property', 'http://www.wikidata.org/prop/direct/P166'), ('propertyName', 'award received')]
# [('property', 'http://www.wikidata.org/prop/direct/P1477'), ('propertyName', 'birth name')]
# [('property', 'http://www.wikidata.org/prop/direct/P509'), ('propertyName', 'cause of death')]
# [('property', 'http://www.wikidata.org/prop/direct/P40'), ('propertyName', 'child')]
# [('property', 'http://www.wikidata.org/prop/direct/P4768'), ('propertyName', 'cinematografo.it name or company ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7763'), ('propertyName', 'copyright status as a creator')]
# [('property', 'http://www.wikidata.org/prop/direct/P27'), ('propertyName', 'country of citizenship')]
# [('property', 'http://www.wikidata.org/prop/direct/P569'), ('propertyName', 'date of birth')]
# [('property', 'http://www.wikidata.org/prop/direct/P570'), ('propertyName', 'date of death')]
# [('property', 'http://www.wikidata.org/prop/direct/P1343'), ('propertyName', 'described by source')]
# [('property', 'http://www.wikidata.org/prop/direct/P1889'), ('propertyName', 'different from')]
# [('property', 'http://www.wikidata.org/prop/direct/P358'), ('propertyName', 'discography')]
# [('property', 'http://www.wikidata.org/prop/direct/P69'), ('propertyName', 'educated at')]
# [('property', 'http://www.wikidata.org/prop/direct/P734'), ('propertyName', 'family name')]
# [('property', 'http://www.wikidata.org/prop/direct/P22'), ('propertyName', 'father')]
# [('property', 'http://www.wikidata.org/prop/direct/P5327'), ('propertyName', 'fernsehserien.de ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1283'), ('propertyName', 'filmography')]
# [('property', 'http://www.wikidata.org/prop/direct/P1819'), ('propertyName', 'genealogics.org person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P136'), ('propertyName', 'genre')]
# [('property', 'http://www.wikidata.org/prop/direct/P735'), ('propertyName', 'given name')]
# [('property', 'http://www.wikidata.org/prop/direct/P4359'), ('propertyName', 'gravsted.dk ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6379'), ('propertyName', 'has works in the collection')]
# [('property', 'http://www.wikidata.org/prop/direct/P18'), ('propertyName', 'image')]
# [('property', 'http://www.wikidata.org/prop/direct/P737'), ('propertyName', 'influenced by')]
# [('property', 'http://www.wikidata.org/prop/direct/P31'), ('propertyName', 'instance of')]
# [('property', 'http://www.wikidata.org/prop/direct/P1303'), ('propertyName', 'instrument')]
# [('property', 'http://www.wikidata.org/prop/direct/P7808'), ('propertyName', 'kino-teatr.ru person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1412'), ('propertyName', 'languages spoken, written or signed')]
# [('property', 'http://www.wikidata.org/prop/direct/P102'), ('propertyName', 'member of political party')]
# [('property', 'http://www.wikidata.org/prop/direct/P241'), ('propertyName', 'military branch')]
# [('property', 'http://www.wikidata.org/prop/direct/P1347'), ('propertyName', 'military casualty classification')]
# [('property', 'http://www.wikidata.org/prop/direct/P25'), ('propertyName', 'mother')]
# [('property', 'http://www.wikidata.org/prop/direct/P1559'), ('propertyName', 'name in native language')]
# [('property', 'http://www.wikidata.org/prop/direct/P103'), ('propertyName', 'native language')]
# [('property', 'http://www.wikidata.org/prop/direct/P97'), ('propertyName', 'noble title')]
# [('property', 'http://www.wikidata.org/prop/direct/P1411'), ('propertyName', 'nominated for')]
# [('property', 'http://www.wikidata.org/prop/direct/P800'), ('propertyName', 'notable work')]
# [('property', 'http://www.wikidata.org/prop/direct/P1971'), ('propertyName', 'number of children')]
# [('property', 'http://www.wikidata.org/prop/direct/P106'), ('propertyName', 'occupation')]
# [('property', 'http://www.wikidata.org/prop/direct/P856'), ('propertyName', 'official website')]
# [('property', 'http://www.wikidata.org/prop/direct/P5008'), ('propertyName', 'on focus list of Wikimedia project')]
# [('property', 'http://www.wikidata.org/prop/direct/P3762'), ('propertyName', 'openMLOL author ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P19'), ('propertyName', 'place of birth')]
# [('property', 'http://www.wikidata.org/prop/direct/P119'), ('propertyName', 'place of burial')]
# [('property', 'http://www.wikidata.org/prop/direct/P20'), ('propertyName', 'place of death')]
# [('property', 'http://www.wikidata.org/prop/direct/P264'), ('propertyName', 'record label')]
# [('property', 'http://www.wikidata.org/prop/direct/P7084'), ('propertyName', 'related category')]
# [('property', 'http://www.wikidata.org/prop/direct/P1038'), ('propertyName', 'relative')]
# [('property', 'http://www.wikidata.org/prop/direct/P140'), ('propertyName', 'religion')]
# [('property', 'http://www.wikidata.org/prop/direct/P551'), ('propertyName', 'residence')]
# [('property', 'http://www.wikidata.org/prop/direct/P21'), ('propertyName', 'sex or gender')]
# [('property', 'http://www.wikidata.org/prop/direct/P3373'), ('propertyName', 'sibling')]
# [('property', 'http://www.wikidata.org/prop/direct/P109'), ('propertyName', 'signature')]
# [('property', 'http://www.wikidata.org/prop/direct/P8687'), ('propertyName', 'social media followers')]
# [('property', 'http://www.wikidata.org/prop/direct/P26'), ('propertyName', 'spouse')]
# [('property', 'http://www.wikidata.org/prop/direct/P2348'), ('propertyName', 'time period')]
# [('property', 'http://www.wikidata.org/prop/direct/P910'), ('propertyName', "topic's main category")]
# [('property', 'http://www.wikidata.org/prop/direct/P937'), ('propertyName', 'work location')]
# [('property', 'http://www.wikidata.org/prop/direct/P2032'), ('propertyName', 'work period (end)')]
# [('property', 'http://www.wikidata.org/prop/direct/P2031'), ('propertyName', 'work period (start)')]
# [('property', 'http://www.wikidata.org/prop/direct/P2605'), ('propertyName', 'ČSFD person ID')]
# 219

# %%
# Return all ingoing properties of every actor that have acted in Halloween
queryString = """
SELECT DISTINCT ?property ?propertyName
WHERE { 

    wd:Q221103 wdt:P161 ?castMember.
    
    # ?castMember <http://schema.org/name> ?castMemberName.
    
    # ?object ?property ?castMember.
    # ?property <http://schema.org/name> ?propertyName.
    
} 
ORDER BY ?propertyName

"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('property', 'http://www.wikidata.org/prop/direct/P1877'), ('propertyName', 'after a work by')]
# [('property', 'http://www.wikidata.org/prop/direct/P161'), ('propertyName', 'cast member')]
# [('property', 'http://www.wikidata.org/prop/direct/P971'), ('propertyName', 'category combines topics')]
# [('property', 'http://www.wikidata.org/prop/direct/P301'), ('propertyName', "category's main topic")]
# [('property', 'http://www.wikidata.org/prop/direct/P40'), ('propertyName', 'child')]
# [('property', 'http://www.wikidata.org/prop/direct/P86'), ('propertyName', 'composer')]
# [('property', 'http://www.wikidata.org/prop/direct/P170'), ('propertyName', 'creator')]
# [('property', 'http://www.wikidata.org/prop/direct/P1889'), ('propertyName', 'different from')]
# [('property', 'http://www.wikidata.org/prop/direct/P57'), ('propertyName', 'director')]
# [('property', 'http://www.wikidata.org/prop/direct/P344'), ('propertyName', 'director of photography')]
# [('property', 'http://www.wikidata.org/prop/direct/P1431'), ('propertyName', 'executive producer')]
# [('property', 'http://www.wikidata.org/prop/direct/P22'), ('propertyName', 'father')]
# [('property', 'http://www.wikidata.org/prop/direct/P1040'), ('propertyName', 'film editor')]
# [('property', 'http://www.wikidata.org/prop/direct/P1290'), ('propertyName', 'godparent')]
# [('property', 'http://www.wikidata.org/prop/direct/P921'), ('propertyName', 'main subject')]
# [('property', 'http://www.wikidata.org/prop/direct/P25'), ('propertyName', 'mother')]
# [('property', 'http://www.wikidata.org/prop/direct/P175'), ('propertyName', 'performer')]
# [('property', 'http://www.wikidata.org/prop/direct/P162'), ('propertyName', 'producer')]
# [('property', 'http://www.wikidata.org/prop/direct/P58'), ('propertyName', 'screenwriter')]
# [('property', 'http://www.wikidata.org/prop/direct/P3373'), ('propertyName', 'sibling')]
# [('property', 'http://www.wikidata.org/prop/direct/P26'), ('propertyName', 'spouse')]
# [('property', 'http://www.wikidata.org/prop/direct/P725'), ('propertyName', 'voice actor')]
# [('property', 'http://www.wikidata.org/prop/direct/P1346'), ('propertyName', 'winner')]
# 23

# %%
# Return all films of every actor that have acted in Halloween
queryString = """
SELECT DISTINCT ?castMemberName ?filmTitle
WHERE { 

    wd:Q221103 wdt:P161 ?castMember.
    
    # ?castMember <http://schema.org/name> ?castMemberName.
    
    # ?film wdt:P161 ?castMember.
    # ?film wdt:P1476 ?filmTitle.
    
} 
ORDER BY ?castMemberName

"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('castMemberName', 'Arthur Malet'), ('filmTitle', 'Vanishing Point')]
# [('castMemberName', 'Arthur Malet'), ('filmTitle', 'Oh, God! You Devil')]
# [('castMemberName', 'Arthur Malet'), ('filmTitle', 'Hook')]
# [('castMemberName', 'Arthur Malet'), ('filmTitle', 'The Waltons')]
# [('castMemberName', 'Arthur Malet'), ('filmTitle', 'Mary Poppins')]
# [('castMemberName', 'Arthur Malet'), ('filmTitle', 'Dallas')]
# [('castMemberName', 'Arthur Malet'), ('filmTitle', 'In the Heat of the Night')]
# [('castMemberName', 'Arthur Malet'), ('filmTitle', 'Heaven Can Wait')]
# [('castMemberName', 'Arthur Malet'), ('filmTitle', 'Wonder Woman')]
# [('castMemberName', 'Arthur Malet'), ('filmTitle', 'Young Frankenstein')]
# [('castMemberName', 'Arthur Malet'), ('filmTitle', 'Lt. Robin Crusoe, U.S.N.')]
# [('castMemberName', 'Arthur Malet'), ('filmTitle', 'King Rat')]
# [('castMemberName', 'Arthur Malet'), ('filmTitle', 'MacGyver')]
# [('castMemberName', 'Arthur Malet'), ('filmTitle', 'Dick Tracy')]
# [('castMemberName', 'Arthur Malet'), ('filmTitle', 'Penelope')]
# [('castMemberName', 'Arthur Malet'), ('filmTitle', 'Halloween')]
# [('castMemberName', 'Arthur Malet'), ('filmTitle', 'The Great White Hope')]
# [('castMemberName', 'Arthur Malet'), ('filmTitle', 'Toys')]
# [('castMemberName', 'Arthur Malet'), ('filmTitle', 'Beastmaster 2: Through the Portal of Time')]
# [('castMemberName', 'Arthur Malet'), ('filmTitle', 'City Heat')]
# [('castMemberName', 'Arthur Malet'), ('filmTitle', 'A Little Princess')]
# [('castMemberName', 'Arthur Malet'), ('filmTitle', 'The Helicopter Spies')]
# [('castMemberName', 'Arthur Malet'), ('filmTitle', 'Worth Winning')]
# [('castMemberName', 'Arthur Malet'), ('filmTitle', 'Munster, Go Home!')]
# [('castMemberName', 'Charles Cyphers'), ('filmTitle', 'Assault on Precinct 13')]
# [('castMemberName', 'Charles Cyphers'), ('filmTitle', 'Murder in the First')]
# [('castMemberName', 'Charles Cyphers'), ('filmTitle', 'Coming Home')]
# [('castMemberName', 'Charles Cyphers'), ('filmTitle', 'The Missiles of October')]
# [('castMemberName', 'Charles Cyphers'), ('filmTitle', 'Halloween')]
# [('castMemberName', 'Charles Cyphers'), ('filmTitle', 'Halloween II')]
# [('castMemberName', 'Charles Cyphers'), ('filmTitle', 'The Onion Field')]
# [('castMemberName', 'Charles Cyphers'), ('filmTitle', 'The Fog')]
# [('castMemberName', 'Charles Cyphers'), ('filmTitle', "Someone's Watching Me!")]
# [('castMemberName', 'Charles Cyphers'), ('filmTitle', 'Major League')]
# [('castMemberName', 'Charles Cyphers'), ('filmTitle', 'Gray Lady Down')]
# [('castMemberName', 'Charles Cyphers'), ('filmTitle', 'Escape from New York')]
# [('castMemberName', 'Donald Pleasence'), ('filmTitle', 'Jaguar Lives!')]
# [('castMemberName', 'Donald Pleasence'), ('filmTitle', 'Telefon')]
# [('castMemberName', 'Donald Pleasence'), ('filmTitle', 'Dracula')]
# [('castMemberName', 'Donald Pleasence'), ('filmTitle', 'The Count of Monte Cristo')]
# [('castMemberName', 'Donald Pleasence'), ('filmTitle', 'Tales That Witness Madness')]
# [('castMemberName', 'Donald Pleasence'), ('filmTitle', 'The Hands of Orlac')]
# [('castMemberName', 'Donald Pleasence'), ('filmTitle', 'Race for the Yankee Zephyr')]
# [('castMemberName', 'Donald Pleasence'), ('filmTitle', 'Trial by Combat')]
# [('castMemberName', 'Donald Pleasence'), ('filmTitle', 'THX 1138')]
# [('castMemberName', 'Donald Pleasence'), ('filmTitle', 'The Greatest Story Ever Told')]
# [('castMemberName', 'Donald Pleasence'), ('filmTitle', 'The Great Escape')]
# [('castMemberName', 'Donald Pleasence'), ('filmTitle', 'You Only Live Twice')]
# [('castMemberName', 'Donald Pleasence'), ('filmTitle', 'The Six Wives of Henry VIII')]
# [('castMemberName', 'Donald Pleasence'), ('filmTitle', 'The Pied Piper')]
# [('castMemberName', 'Donald Pleasence'), ('filmTitle', 'Where Is Parsifal?')]
# [('castMemberName', 'Donald Pleasence'), ('filmTitle', "Frankenstein's Great Aunt Tillie")]
# [('castMemberName', 'Donald Pleasence'), ('filmTitle', 'Wedding in White')]
# [('castMemberName', 'Donald Pleasence'), ('filmTitle', 'Alone in the Dark')]
# [('castMemberName', 'Donald Pleasence'), ('filmTitle', 'The Man with the Power')]
# [('castMemberName', 'Donald Pleasence'), ('filmTitle', 'Barry McKenzie Holds His Own')]
# [('castMemberName', 'Donald Pleasence'), ('filmTitle', 'All Quiet on the Western Front')]
# [('castMemberName', 'Donald Pleasence'), ('filmTitle', 'The Last Tycoon')]
# [('castMemberName', 'Donald Pleasence'), ('filmTitle', 'Black Arrow')]
# [('castMemberName', 'Donald Pleasence'), ('filmTitle', 'Jesus of Nazareth')]
# [('castMemberName', 'Donald Pleasence'), ('filmTitle', 'The Black Windmill')]
# [('castMemberName', 'Donald Pleasence'), ('filmTitle', "Dario Argento's World of Horror")]
# [('castMemberName', 'Donald Pleasence'), ('filmTitle', 'Der Commander')]
# [('castMemberName', 'Donald Pleasence'), ('filmTitle', 'A Tale of Two Cities')]
# [('castMemberName', 'Donald Pleasence'), ('filmTitle', 'Matchless')]
# [('castMemberName', 'Donald Pleasence'), ('filmTitle', 'Witness for the Prosecution')]
# [('castMemberName', 'Donald Pleasence'), ('filmTitle', 'Halloween')]
# [('castMemberName', 'Donald Pleasence'), ('filmTitle', 'The Eagle Has Landed')]
# [('castMemberName', 'Donald Pleasence'), ('filmTitle', 'The Horsemasters')]
# [('castMemberName', 'Donald Pleasence'), ('filmTitle', 'Killers of Kilimanjaro')]
# [('castMemberName', 'Donald Pleasence'), ('filmTitle', 'The Wind Cannot Read')]
# [('castMemberName', 'Donald Pleasence'), ('filmTitle', 'Halloween II')]
# [('castMemberName', 'Donald Pleasence'), ('filmTitle', 'The Hallelujah Trail')]
# [('castMemberName', 'Donald Pleasence'), ('filmTitle', 'Fantastic Voyage')]
# [('castMemberName', 'Donald Pleasence'), ('filmTitle', 'Eye of the Devil')]
# [('castMemberName', 'Donald Pleasence'), ('filmTitle', 'A Breed Apart')]
# [('castMemberName', 'Donald Pleasence'), ('filmTitle', 'Last Platoon')]
# [('castMemberName', 'Donald Pleasence'), ('filmTitle', 'Arch of Triumph')]
# [('castMemberName', 'Donald Pleasence'), ('filmTitle', 'Blood Relatives')]
# [('castMemberName', 'Donald Pleasence'), ('filmTitle', 'Sons and Lovers')]
# [('castMemberName', 'Donald Pleasence'), ('filmTitle', 'Oh, God!')]
# [('castMemberName', 'Donald Pleasence'), ('filmTitle', 'The Flesh and the Fiends')]
# [('castMemberName', 'Donald Pleasence'), ('filmTitle', 'Land of the Minotaur')]
# [('castMemberName', 'Donald Pleasence'), ('filmTitle', 'Halloween 4: The Return of Michael Myers')]
# [('castMemberName', 'Donald Pleasence'), ('filmTitle', 'Halloween 5: The Revenge of Michael Myers')]
# [('castMemberName', 'Donald Pleasence'), ('filmTitle', 'River of Death')]
# [('castMemberName', 'Donald Pleasence'), ('filmTitle', 'Casablanca Express')]
# [('castMemberName', 'Donald Pleasence'), ('filmTitle', 'The Passover Plot')]
# [('castMemberName', 'Donald Pleasence'), ('filmTitle', 'The Caretaker')]
# [('castMemberName', 'Donald Pleasence'), ('filmTitle', '1984')]
# [('castMemberName', 'Donald Pleasence'), ('filmTitle', 'The Ambassador')]
# [('castMemberName', 'Donald Pleasence'), ('filmTitle', 'Will Penny')]
# [('castMemberName', 'Donald Pleasence'), ('filmTitle', 'The Beachcomber')]
# [('castMemberName', 'Donald Pleasence'), ('filmTitle', 'The Madwoman of Chaillot')]
# [('castMemberName', 'Donald Pleasence'), ('filmTitle', 'Shadows and Fog')]
# [('castMemberName', 'Donald Pleasence'), ('filmTitle', 'Treasure of the Amazon')]
# [('castMemberName', 'Donald Pleasence'), ('filmTitle', 'Arthur! Arthur!')]
# [('castMemberName', 'Donald Pleasence'), ('filmTitle', 'Cul-de-sac')]
# [('castMemberName', 'Donald Pleasence'), ('filmTitle', 'Kidnapped')]
# [('castMemberName', 'Donald Pleasence'), ('filmTitle', 'Halloween: The Curse of Michael Myers')]
# [('castMemberName', 'Donald Pleasence'), ('filmTitle', 'From Beyond the Grave')]
# [('castMemberName', 'Donald Pleasence'), ('filmTitle', 'What a Carve Up!')]
# [('castMemberName', 'Donald Pleasence'), ('filmTitle', 'The Other People')]
# [('castMemberName', 'Donald Pleasence'), ('filmTitle', 'The Uncanny')]
# [('castMemberName', 'Donald Pleasence'), ('filmTitle', 'The French Atlantic Affair')]
# [('castMemberName', 'Donald Pleasence'), ('filmTitle', 'Terror in the Aisles')]
# [('castMemberName', 'Donald Pleasence'), ('filmTitle', 'The Mutations')]
# [('castMemberName', 'Donald Pleasence'), ('filmTitle', 'No Love for Johnnie')]
# [('castMemberName', 'Donald Pleasence'), ('filmTitle', 'Heart of a Child')]
# [('castMemberName', 'Donald Pleasence'), ('filmTitle', 'Escape to Witch Mountain')]
# [('castMemberName', 'Donald Pleasence'), ('filmTitle', 'Power Play')]
# [('castMemberName', 'Donald Pleasence'), ('filmTitle', 'Mr. Freedom')]
# [('castMemberName', 'Donald Pleasence'), ('filmTitle', 'The Wind of Change')]
# [('castMemberName', 'Donald Pleasence'), ('filmTitle', 'Wake in Fright')]
# [('castMemberName', 'Donald Pleasence'), ('filmTitle', 'The Big Day')]
# [('castMemberName', 'Donald Pleasence'), ('filmTitle', "Sgt. Pepper's Lonely Hearts Club Band")]
# [('castMemberName', 'Donald Pleasence'), ('filmTitle', 'Spare the Rod')]
# [('castMemberName', 'Donald Pleasence'), ('filmTitle', 'Soldier Blue')]
# [('castMemberName', 'Donald Pleasence'), ('filmTitle', 'Journey into Fear')]
# [('castMemberName', 'Donald Pleasence'), ('filmTitle', 'Prince of Darkness')]
# [('castMemberName', 'Donald Pleasence'), ('filmTitle', 'Buried Alive')]
# [('castMemberName', 'Donald Pleasence'), ('filmTitle', 'Innocent Bystanders')]
# [('castMemberName', 'Donald Pleasence'), ('filmTitle', 'Escape from New York')]
# [('castMemberName', 'Donald Pleasence'), ('filmTitle', 'The Inspector')]
# [('castMemberName', 'Donald Pleasence'), ('filmTitle', 'The Monster Club')]
# [('castMemberName', 'Donald Pleasence'), ('filmTitle', 'The Hour of the Pig')]
# [('castMemberName', 'Donald Pleasence'), ('filmTitle', 'The Jerusalem File')]
# [('castMemberName', 'Donald Pleasence'), ('filmTitle', 'Death Line')]
# [('castMemberName', 'Donald Pleasence'), ('filmTitle', "I Don't Want to Be Born")]
# [('castMemberName', 'Donald Pleasence'), ('filmTitle', 'The Black Tent')]
# [('castMemberName', 'Donald Pleasence'), ('filmTitle', 'Ten Little Indians')]
# [('castMemberName', 'Donald Pleasence'), ('filmTitle', 'Dr. Crippen')]
# [('castMemberName', 'Donald Pleasence'), ('filmTitle', 'The Night of the Generals')]
# [('castMemberName', 'Donald Pleasence'), ('filmTitle', 'The Pumaman')]
# [('castMemberName', 'Donald Pleasence'), ('filmTitle', 'Look Back in Anger')]
# [('castMemberName', 'Donald Pleasence'), ('filmTitle', 'Warrior of the Lost World')]
# [('castMemberName', 'Donald Pleasence'), ('filmTitle', 'Fatal frames: Fotogrammi mortali')]
# [('castMemberName', 'Donald Pleasence'), ('filmTitle', 'Going to Pieces: The Rise and Fall of the Slasher Film')]
# [('castMemberName', 'Donald Pleasence'), ('filmTitle', 'Ground Zero')]
# [('castMemberName', 'Donald Pleasence'), ('filmTitle', 'Hearts of the West')]
# [('castMemberName', 'Donald Pleasence'), ('filmTitle', 'The House of Usher')]
# [('castMemberName', 'Donald Pleasence'), ('filmTitle', 'Hell Is a City')]
# [('castMemberName', 'Donald Pleasence'), ('filmTitle', 'Circus of Horrors')]
# [('castMemberName', 'Donald Pleasence'), ('filmTitle', "Hanna's War")]
# [('castMemberName', 'Donald Pleasence'), ('filmTitle', 'Out of the Darkness')]
# [('castMemberName', 'Gabriel Cattand'), ('filmTitle', 'Halloween')]
# [('castMemberName', 'Gabriel Cattand'), ('filmTitle', 'Story of O')]
# [('castMemberName', 'Jamie Lee Curtis'), ('filmTitle', 'The Tailor of Panama')]
# [('castMemberName', 'Jamie Lee Curtis'), ('filmTitle', 'Freaky Friday')]
# [('castMemberName', 'Jamie Lee Curtis'), ('filmTitle', 'Homegrown')]
# [('castMemberName', 'Jamie Lee Curtis'), ('filmTitle', 'True Lies')]
# [('castMemberName', 'Jamie Lee Curtis'), ('filmTitle', 'New Girl')]
# [('castMemberName', 'Jamie Lee Curtis'), ('filmTitle', 'Trading Places')]
# [('castMemberName', 'Jamie Lee Curtis'), ('filmTitle', 'Virus')]
# [('castMemberName', 'Jamie Lee Curtis'), ('filmTitle', 'Scream Queens')]
# [('castMemberName', 'Jamie Lee Curtis'), ('filmTitle', 'Love Letters')]
# [('castMemberName', 'Jamie Lee Curtis'), ('filmTitle', 'Veronica Mars')]
# [('castMemberName', 'Jamie Lee Curtis'), ('filmTitle', 'Anything but Love')]
# [('castMemberName', 'Jamie Lee Curtis'), ('filmTitle', 'Drowning Mona')]
# [('castMemberName', 'Jamie Lee Curtis'), ('filmTitle', 'The Kid & I')]
# [('castMemberName', 'Jamie Lee Curtis'), ('filmTitle', 'House Arrest')]
# [('castMemberName', 'Jamie Lee Curtis'), ('filmTitle', 'Halloween')]
# [('castMemberName', 'Jamie Lee Curtis'), ('filmTitle', 'A Fish Called Wanda')]
# [('castMemberName', 'Jamie Lee Curtis'), ('filmTitle', 'Halloween H20: 20 Years Later')]
# [('castMemberName', 'Jamie Lee Curtis'), ('filmTitle', 'Halloween: Resurrection')]
# [('castMemberName', 'Jamie Lee Curtis'), ('filmTitle', 'The Little Engine That Could')]
# [('castMemberName', 'Jamie Lee Curtis'), ('filmTitle', 'Queens Logic')]
# [('castMemberName', 'Jamie Lee Curtis'), ('filmTitle', 'Halloween II')]
# [('castMemberName', 'Jamie Lee Curtis'), ('filmTitle', 'Halloween Kills')]
# [('castMemberName', 'Jamie Lee Curtis'), ('filmTitle', 'Halloween III: Season of the Witch')]
# [('castMemberName', 'Jamie Lee Curtis'), ('filmTitle', 'The Fog')]
# [('castMemberName', 'Jamie Lee Curtis'), ('filmTitle', 'Death of a Centerfold: The Dorothy Stratten Story')]
# [('castMemberName', 'Jamie Lee Curtis'), ('filmTitle', 'Bad Boys')]
# [('castMemberName', 'Jamie Lee Curtis'), ('filmTitle', 'Blue Steel')]
# [('castMemberName', 'Jamie Lee Curtis'), ('filmTitle', "Nicholas' Gift")]
# [('castMemberName', 'Jamie Lee Curtis'), ('filmTitle', 'Grandview')]
# [('castMemberName', 'Jamie Lee Curtis'), ('filmTitle', 'Knives Out')]
# [('castMemberName', 'Jamie Lee Curtis'), ('filmTitle', 'Perfect')]
# [('castMemberName', 'Jamie Lee Curtis'), ('filmTitle', 'Terror Train')]
# [('castMemberName', 'Jamie Lee Curtis'), ('filmTitle', 'Coming Soon')]
# [('castMemberName', 'Jamie Lee Curtis'), ('filmTitle', 'Christmas with the Kranks')]
# [('castMemberName', 'Jamie Lee Curtis'), ('filmTitle', 'The Heidi Chronicles')]
# [('castMemberName', 'Jamie Lee Curtis'), ('filmTitle', 'Roadgames')]
# [('castMemberName', 'Jamie Lee Curtis'), ('filmTitle', 'An Acceptable Loss')]
# [('castMemberName', 'Jamie Lee Curtis'), ('filmTitle', 'My Girl 2')]
# [('castMemberName', 'Jamie Lee Curtis'), ('filmTitle', 'My Girl')]
# [('castMemberName', 'Jamie Lee Curtis'), ('filmTitle', 'Terror in the Aisles')]
# [('castMemberName', 'Jamie Lee Curtis'), ('filmTitle', 'Prom Night')]
# [('castMemberName', 'Jamie Lee Curtis'), ('filmTitle', 'You Again')]
# [('castMemberName', 'Jamie Lee Curtis'), ('filmTitle', 'Forever Young')]
# [('castMemberName', 'Jamie Lee Curtis'), ('filmTitle', 'Fierce Creatures')]
# [('castMemberName', 'Jamie Lee Curtis'), ('filmTitle', 'Beverly Hills Chihuahua')]
# [('castMemberName', 'Jamie Lee Curtis'), ('filmTitle', 'The Adventures of Buckaroo Banzai Across the 8th Dimension')]
# [('castMemberName', 'Jamie Lee Curtis'), ('filmTitle', 'Escape from New York')]
# [('castMemberName', 'Jamie Lee Curtis'), ('filmTitle', 'Dominick and Eugene')]
# [('castMemberName', 'Jamie Lee Curtis'), ('filmTitle', 'The American Nightmare')]
# [('castMemberName', 'Jamie Lee Curtis'), ('filmTitle', "Mother's Boys")]
# [('castMemberName', 'Jamie Lee Curtis'), ('filmTitle', 'Amazing Grace and Chuck')]
# [('castMemberName', 'Jamie Lee Curtis'), ('filmTitle', 'As Summers Die')]
# [('castMemberName', 'John Carpenter'), ('filmTitle', 'Big Trouble in Little China')]
# [('castMemberName', 'John Carpenter'), ('filmTitle', 'In Search of Darkness')]
# [('castMemberName', 'John Carpenter'), ('filmTitle', 'The Silence of the Hams')]
# [('castMemberName', 'John Carpenter'), ('filmTitle', 'The Thing')]
# [('castMemberName', 'John Carpenter'), ('filmTitle', 'Body Bags')]
# [('castMemberName', 'John Carpenter'), ('filmTitle', 'Halloween')]
# [('castMemberName', 'John Carpenter'), ('filmTitle', 'Network')]
# [('castMemberName', 'John Carpenter'), ('filmTitle', 'Lovecraft: Fear of the Unknown')]
# [('castMemberName', 'John Carpenter'), ('filmTitle', 'The Fog')]
# [('castMemberName', 'John Carpenter'), ('filmTitle', 'Dark Star')]
# [('castMemberName', 'John Carpenter'), ('filmTitle', 'Village of the Damned')]
# [('castMemberName', 'John Carpenter'), ('filmTitle', 'The Boy Who Could Fly')]
# [('castMemberName', 'John Carpenter'), ('filmTitle', 'Memoirs of an Invisible Man')]
# [('castMemberName', 'John Carpenter'), ('filmTitle', 'Dead On: The Life and Cinema of George A. Romero')]
# [('castMemberName', 'John Carpenter'), ('filmTitle', 'Nightmares in Red, White and Blue')]
# [('castMemberName', 'John Carpenter'), ('filmTitle', 'Starman')]
# [('castMemberName', 'John Carpenter'), ('filmTitle', 'Escape from New York')]
# [('castMemberName', 'John Carpenter'), ('filmTitle', 'The American Nightmare')]
# [('castMemberName', 'John Carpenter'), ('filmTitle', 'Going to Pieces: The Rise and Fall of the Slasher Film')]
# [('castMemberName', 'John Michael Graham'), ('filmTitle', 'Grease')]
# [('castMemberName', 'John Michael Graham'), ('filmTitle', 'Halloween')]
# [('castMemberName', 'Kyle Richards'), ('filmTitle', "National Lampoon's Pledge This!")]
# [('castMemberName', 'Kyle Richards'), ('filmTitle', 'The Real Housewives of Beverly Hills')]
# [('castMemberName', 'Kyle Richards'), ('filmTitle', 'Halloween')]
# [('castMemberName', 'Kyle Richards'), ('filmTitle', 'Halloween II')]
# [('castMemberName', 'Kyle Richards'), ('filmTitle', 'The Car')]
# [('castMemberName', 'Kyle Richards'), ('filmTitle', 'Curfew')]
# [('castMemberName', 'Kyle Richards'), ('filmTitle', 'Escape to Witch Mountain')]
# [('castMemberName', 'Kyle Richards'), ('filmTitle', 'The Hungover Games')]
# [('castMemberName', 'Kyle Richards'), ('filmTitle', 'Eaten Alive')]
# [('castMemberName', 'Kyle Richards'), ('filmTitle', 'Video from Hell')]
# [('castMemberName', 'Kyle Richards'), ('filmTitle', 'The Watcher in the Woods')]
# [('castMemberName', 'Nancy Kyes'), ('filmTitle', 'Assault on Precinct 13')]
# [('castMemberName', 'Nancy Kyes'), ('filmTitle', 'Halloween')]
# [('castMemberName', 'Nancy Kyes'), ('filmTitle', 'Halloween II')]
# [('castMemberName', 'Nancy Kyes'), ('filmTitle', 'Halloween III: Season of the Witch')]
# [('castMemberName', 'Nancy Kyes'), ('filmTitle', 'The Fog')]
# [('castMemberName', 'Nancy Stephens'), ('filmTitle', 'Halloween')]
# [('castMemberName', 'Nancy Stephens'), ('filmTitle', 'Halloween H20: 20 Years Later')]
# [('castMemberName', 'Nancy Stephens'), ('filmTitle', 'Halloween II')]
# [('castMemberName', 'Nancy Stephens'), ('filmTitle', 'D2: The Mighty Ducks')]
# [('castMemberName', 'Nick Castle'), ('filmTitle', 'In Search of Darkness')]
# [('castMemberName', 'Nick Castle'), ('filmTitle', 'Halloween')]
# [('castMemberName', 'Nick Castle'), ('filmTitle', 'Dark Star')]
# [('castMemberName', 'Nick Castle'), ('filmTitle', 'The Boy Who Could Fly')]
# [('castMemberName', 'Nick Castle'), ('filmTitle', 'Escape from New York')]
# [('castMemberName', 'P. J. Soles'), ('filmTitle', 'The Boy in the Plastic Bubble')]
# [('castMemberName', 'P. J. Soles'), ('filmTitle', 'Carrie')]
# [('castMemberName', 'P. J. Soles'), ('filmTitle', "The Devil's Rejects")]
# [('castMemberName', 'P. J. Soles'), ('filmTitle', 'Alone in the Dark II')]
# [('castMemberName', 'P. J. Soles'), ('filmTitle', 'Imps*')]
# [('castMemberName', 'P. J. Soles'), ('filmTitle', 'Airwolf')]
# [('castMemberName', 'P. J. Soles'), ('filmTitle', 'Breaking Away')]
# [('castMemberName', 'P. J. Soles'), ('filmTitle', 'Innocent Prey')]
# [('castMemberName', 'P. J. Soles'), ('filmTitle', 'Sweet Dreams')]
# [('castMemberName', 'P. J. Soles'), ('filmTitle', 'Halloween')]
# [('castMemberName', 'P. J. Soles'), ('filmTitle', 'Stripes')]
# [('castMemberName', 'P. J. Soles'), ('filmTitle', 'Jawbreaker')]
# [('castMemberName', 'P. J. Soles'), ('filmTitle', 'Mil Mascaras vs. the Aztec Mummy')]
# [('castMemberName', 'P. J. Soles'), ('filmTitle', 'The Butterfly Room')]
# [('castMemberName', 'P. J. Soles'), ('filmTitle', 'Old Boyfriends')]
# [('castMemberName', 'P. J. Soles'), ('filmTitle', 'Alienator')]
# [('castMemberName', 'P. J. Soles'), ('filmTitle', 'The Other Woman')]
# [('castMemberName', 'P. J. Soles'), ('filmTitle', 'Terror in the Aisles')]
# [('castMemberName', 'P. J. Soles'), ('filmTitle', 'Blast')]
# [('castMemberName', 'P. J. Soles'), ('filmTitle', "Rock 'n' Roll High School")]
# [('castMemberName', 'P. J. Soles'), ('filmTitle', 'Private Benjamin')]
# [('castMemberName', 'P. J. Soles'), ('filmTitle', 'Uncle Sam')]
# [('castMemberName', 'Tony Moran'), ('filmTitle', 'The Waltons')]
# [('castMemberName', 'Tony Moran'), ('filmTitle', 'Halloween')]
# [('castMemberName', 'Tony Moran'), ('filmTitle', 'Halloween II')]
# [('castMemberName', 'Tony Moran'), ('filmTitle', 'Going to Pieces: The Rise and Fall of the Slasher Film')]
# 271

# %%
# Return all awards of every actor that have acted in Halloween
queryString = """
SELECT DISTINCT ?castMemberName ?awardName
WHERE { 

    wd:Q221103 wdt:P161 ?castMember.
    
    # ?castMember <http://schema.org/name> ?castMemberName.
    
    # ?castMember wdt:P166 ?award.
    # ?award <http://schema.org/name> ?awardName.
    
} 
ORDER BY ?castMemberName

"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('castMemberName', 'Donald Pleasence'), ('awardName', 'Officer of the Order of the British Empire')]
# [('castMemberName', 'Jamie Lee Curtis'), ('awardName', 'Golden Globe Award for Best Actress – Motion Picture Musical or Comedy')]
# [('castMemberName', 'Jamie Lee Curtis'), ('awardName', 'star on Hollywood Walk of Fame')]
# [('castMemberName', 'Jamie Lee Curtis'), ('awardName', 'BAFTA Award for Best Actress in a Supporting Role')]
# 4

# %%
# Return all awards of every actor that have acted in Halloween
queryString = """
SELECT DISTINCT ?castMemberName ?awardName
WHERE { 

    wd:Q221103 wdt:P161 ?castMember.
    
    # ?castMember <http://schema.org/name> ?castMemberName.
    
    # ?award wdt:P1346 ?castMember.
    # ?award <http://schema.org/name> ?awardName.
    
} 
ORDER BY ?castMemberName

"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('castMemberName', 'Donald Pleasence'), ('awardName', 'British Academy Television Award for Best Actor')]
# [('castMemberName', 'Jamie Lee Curtis'), ('awardName', 'Saturn Award for Best Actress')]
# [('castMemberName', 'Jamie Lee Curtis'), ('awardName', 'BAFTA Award for Best Actress in a Supporting Role')]
# 3

# %%
# Return the publication dates of both films
queryString = """
SELECT DISTINCT ?title ?publicationDate
WHERE { 

    {
        wd:Q221103 wdt:P577 ?publicationDate.
        wd:Q221103 wdt:P1476 ?title
    }
    UNION
    {
        wd:Q1243029 wdt:P577 ?publicationDate.
        wd:Q1243029 wdt:P1476 ?title
    }
    
} 

"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('title', 'Halloween'), ('publicationDate', '1978-10-25T00:00:00Z')]
# [('title', 'Halloween'), ('publicationDate', '1979-07-06T00:00:00Z')]
# [('title', 'Halloween'), ('publicationDate', '1979-08-06T00:00:00Z')]
# [('title', 'Friday the 13th'), ('publicationDate', '1980-05-09T00:00:00Z')]
# [('title', 'Friday the 13th'), ('publicationDate', '1980-10-23T00:00:00Z')]
# [('title', 'Friday the 13th'), ('publicationDate', '1980-11-10T00:00:00Z')]
# 6

# %%
# Return the most famous actor that acted in Halloween (consider both number of films and awards)
queryString = """
SELECT ?castMemberName (COUNT(?filmOrAward) AS ?fameScore)
WHERE { 

    wd:Q221103 wdt:P161 ?castMember.
    
    # ?castMember <http://schema.org/name> ?castMemberName.
    
    {
        # ?filmOrAward wdt:P161 ?castMember.
    }
    UNION
    {
        # ?castMember wdt:P166 ?filmOrAward.
    }
    UNION
    {
        # ?filmOrAward wdt:P1346 ?castMember.
    }
    
}
GROUP BY ?castMemberName
ORDER BY DESC (?fameScore)
LIMIT 1

"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('castMemberName', 'Donald Pleasence'), ('fameScore', '130')]
# 1

# %%
# Return all films of every actor that have acted in Halloween at the time of the release

queryString = """
SELECT DISTINCT ?castMemberName ?filmTitle ?filmPublicationDate
WHERE { 

    wd:Q221103 wdt:P161 ?castMember.
    
    # ?castMember <http://schema.org/name> ?castMemberName.
    
    # ?film wdt:P161 ?castMember.
    # ?film wdt:P1476 ?filmTitle.
    # ?film wdt:P577 ?filmPublicationDate.
    
    FILTER(?filmPublicationDate < '1978-10-25T00:00:00Z'^^xsd:dateTime)
} 
ORDER BY ?castMemberName

"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('castMemberName', 'Arthur Malet'), ('filmTitle', 'Vanishing Point'), ('filmPublicationDate', '1971-01-01T00:00:00Z')]
# [('castMemberName', 'Arthur Malet'), ('filmTitle', 'Mary Poppins'), ('filmPublicationDate', '1964-10-01T00:00:00Z')]
# [('castMemberName', 'Arthur Malet'), ('filmTitle', 'Mary Poppins'), ('filmPublicationDate', '1965-08-23T00:00:00Z')]
# [('castMemberName', 'Arthur Malet'), ('filmTitle', 'Mary Poppins'), ('filmPublicationDate', '1965-10-22T00:00:00Z')]
# [('castMemberName', 'Arthur Malet'), ('filmTitle', 'In the Heat of the Night'), ('filmPublicationDate', '1967-08-02T00:00:00Z')]
# [('castMemberName', 'Arthur Malet'), ('filmTitle', 'Heaven Can Wait'), ('filmPublicationDate', '1978-06-28T00:00:00Z')]
# [('castMemberName', 'Arthur Malet'), ('filmTitle', 'Young Frankenstein'), ('filmPublicationDate', '1974-12-15T00:00:00Z')]
# [('castMemberName', 'Arthur Malet'), ('filmTitle', 'Young Frankenstein'), ('filmPublicationDate', '1975-09-05T00:00:00Z')]
# [('castMemberName', 'Arthur Malet'), ('filmTitle', 'Lt. Robin Crusoe, U.S.N.'), ('filmPublicationDate', '1966-06-29T00:00:00Z')]
# [('castMemberName', 'Arthur Malet'), ('filmTitle', 'King Rat'), ('filmPublicationDate', '1965-01-01T00:00:00Z')]
# [('castMemberName', 'Arthur Malet'), ('filmTitle', 'Penelope'), ('filmPublicationDate', '1966-01-01T00:00:00Z')]
# [('castMemberName', 'Arthur Malet'), ('filmTitle', 'The Great White Hope'), ('filmPublicationDate', '1970-01-01T00:00:00Z')]
# [('castMemberName', 'Arthur Malet'), ('filmTitle', 'The Helicopter Spies'), ('filmPublicationDate', '1968-01-01T00:00:00Z')]
# [('castMemberName', 'Arthur Malet'), ('filmTitle', 'Munster, Go Home!'), ('filmPublicationDate', '1966-01-01T00:00:00Z')]
# [('castMemberName', 'Charles Cyphers'), ('filmTitle', 'Assault on Precinct 13'), ('filmPublicationDate', '1976-01-01T00:00:00Z')]
# [('castMemberName', 'Charles Cyphers'), ('filmTitle', 'Coming Home'), ('filmPublicationDate', '1978-01-01T00:00:00Z')]
# [('castMemberName', 'Charles Cyphers'), ('filmTitle', 'The Missiles of October'), ('filmPublicationDate', '1974-12-18T00:00:00Z')]
# [('castMemberName', 'Charles Cyphers'), ('filmTitle', "Someone's Watching Me!"), ('filmPublicationDate', '1978-01-01T00:00:00Z')]
# [('castMemberName', 'Charles Cyphers'), ('filmTitle', 'Gray Lady Down'), ('filmPublicationDate', '1978-03-10T00:00:00Z')]
# [('castMemberName', 'Charles Cyphers'), ('filmTitle', 'Gray Lady Down'), ('filmPublicationDate', '1978-03-22T00:00:00Z')]
# [('castMemberName', 'Charles Cyphers'), ('filmTitle', 'Gray Lady Down'), ('filmPublicationDate', '1978-03-23T00:00:00Z')]
# [('castMemberName', 'Charles Cyphers'), ('filmTitle', 'Gray Lady Down'), ('filmPublicationDate', '1978-04-10T00:00:00Z')]
# [('castMemberName', 'Charles Cyphers'), ('filmTitle', 'Gray Lady Down'), ('filmPublicationDate', '1978-04-14T00:00:00Z')]
# [('castMemberName', 'Charles Cyphers'), ('filmTitle', 'Gray Lady Down'), ('filmPublicationDate', '1978-04-22T00:00:00Z')]
# [('castMemberName', 'Charles Cyphers'), ('filmTitle', 'Gray Lady Down'), ('filmPublicationDate', '1978-04-27T00:00:00Z')]
# [('castMemberName', 'Charles Cyphers'), ('filmTitle', 'Gray Lady Down'), ('filmPublicationDate', '1978-05-11T00:00:00Z')]
# [('castMemberName', 'Charles Cyphers'), ('filmTitle', 'Gray Lady Down'), ('filmPublicationDate', '1978-05-12T00:00:00Z')]
# [('castMemberName', 'Charles Cyphers'), ('filmTitle', 'Gray Lady Down'), ('filmPublicationDate', '1978-06-09T00:00:00Z')]
# [('castMemberName', 'Charles Cyphers'), ('filmTitle', 'Gray Lady Down'), ('filmPublicationDate', '1978-08-07T00:00:00Z')]
# [('castMemberName', 'Charles Cyphers'), ('filmTitle', 'Gray Lady Down'), ('filmPublicationDate', '1978-08-29T00:00:00Z')]
# [('castMemberName', 'Charles Cyphers'), ('filmTitle', 'Gray Lady Down'), ('filmPublicationDate', '1978-08-31T00:00:00Z')]
# [('castMemberName', 'Charles Cyphers'), ('filmTitle', 'Gray Lady Down'), ('filmPublicationDate', '1978-09-07T00:00:00Z')]
# [('castMemberName', 'Donald Pleasence'), ('filmTitle', 'Telefon'), ('filmPublicationDate', '1977-01-01T00:00:00Z')]
# [('castMemberName', 'Donald Pleasence'), ('filmTitle', 'The Count of Monte Cristo'), ('filmPublicationDate', '1975-01-10T00:00:00Z')]
# [('castMemberName', 'Donald Pleasence'), ('filmTitle', 'Tales That Witness Madness'), ('filmPublicationDate', '1973-01-01T00:00:00Z')]
# [('castMemberName', 'Donald Pleasence'), ('filmTitle', 'The Hands of Orlac'), ('filmPublicationDate', '1960-01-01T00:00:00Z')]
# [('castMemberName', 'Donald Pleasence'), ('filmTitle', 'The Hands of Orlac'), ('filmPublicationDate', '1961-01-01T00:00:00Z')]
# [('castMemberName', 'Donald Pleasence'), ('filmTitle', 'Trial by Combat'), ('filmPublicationDate', '1976-01-01T00:00:00Z')]
# [('castMemberName', 'Donald Pleasence'), ('filmTitle', 'THX 1138'), ('filmPublicationDate', '1971-03-11T00:00:00Z')]
# [('castMemberName', 'Donald Pleasence'), ('filmTitle', 'The Greatest Story Ever Told'), ('filmPublicationDate', '1965-01-01T00:00:00Z')]
# [('castMemberName', 'Donald Pleasence'), ('filmTitle', 'The Great Escape'), ('filmPublicationDate', '1963-01-01T00:00:00Z')]
# [('castMemberName', 'Donald Pleasence'), ('filmTitle', 'You Only Live Twice'), ('filmPublicationDate', '1967-06-12T00:00:00Z')]
# [('castMemberName', 'Donald Pleasence'), ('filmTitle', 'You Only Live Twice'), ('filmPublicationDate', '1967-09-14T00:00:00Z')]
# [('castMemberName', 'Donald Pleasence'), ('filmTitle', 'The Six Wives of Henry VIII'), ('filmPublicationDate', '1972-01-01T00:00:00Z')]
# [('castMemberName', 'Donald Pleasence'), ('filmTitle', 'The Pied Piper'), ('filmPublicationDate', '1972-01-01T00:00:00Z')]
# [('castMemberName', 'Donald Pleasence'), ('filmTitle', 'Wedding in White'), ('filmPublicationDate', '1972-10-20T00:00:00Z')]
# [('castMemberName', 'Donald Pleasence'), ('filmTitle', 'The Man with the Power'), ('filmPublicationDate', '1963-10-07T00:00:00Z')]
# [('castMemberName', 'Donald Pleasence'), ('filmTitle', 'Barry McKenzie Holds His Own'), ('filmPublicationDate', '1974-01-01T00:00:00Z')]
# [('castMemberName', 'Donald Pleasence'), ('filmTitle', 'The Last Tycoon'), ('filmPublicationDate', '1976-11-17T00:00:00Z')]
# [('castMemberName', 'Donald Pleasence'), ('filmTitle', 'The Last Tycoon'), ('filmPublicationDate', '1977-03-11T00:00:00Z')]
# [('castMemberName', 'Donald Pleasence'), ('filmTitle', 'Jesus of Nazareth'), ('filmPublicationDate', '1977-01-01T00:00:00Z')]
# [('castMemberName', 'Donald Pleasence'), ('filmTitle', 'The Black Windmill'), ('filmPublicationDate', '1974-01-01T00:00:00Z')]
# [('castMemberName', 'Donald Pleasence'), ('filmTitle', 'A Tale of Two Cities'), ('filmPublicationDate', '1958-01-01T00:00:00Z')]
# [('castMemberName', 'Donald Pleasence'), ('filmTitle', 'Matchless'), ('filmPublicationDate', '1967-01-01T00:00:00Z')]
# [('castMemberName', 'Donald Pleasence'), ('filmTitle', 'The Eagle Has Landed'), ('filmPublicationDate', '1976-12-25T00:00:00Z')]
# [('castMemberName', 'Donald Pleasence'), ('filmTitle', 'The Eagle Has Landed'), ('filmPublicationDate', '1977-01-26T00:00:00Z')]
# [('castMemberName', 'Donald Pleasence'), ('filmTitle', 'The Eagle Has Landed'), ('filmPublicationDate', '1977-02-24T00:00:00Z')]
# [('castMemberName', 'Donald Pleasence'), ('filmTitle', 'The Eagle Has Landed'), ('filmPublicationDate', '1977-03-31T00:00:00Z')]
# [('castMemberName', 'Donald Pleasence'), ('filmTitle', 'The Eagle Has Landed'), ('filmPublicationDate', '1977-04-02T00:00:00Z')]
# [('castMemberName', 'Donald Pleasence'), ('filmTitle', 'The Eagle Has Landed'), ('filmPublicationDate', '1977-04-05T00:00:00Z')]
# [('castMemberName', 'Donald Pleasence'), ('filmTitle', 'The Eagle Has Landed'), ('filmPublicationDate', '1977-04-12T00:00:00Z')]
# [('castMemberName', 'Donald Pleasence'), ('filmTitle', 'The Eagle Has Landed'), ('filmPublicationDate', '1977-04-13T00:00:00Z')]
# [('castMemberName', 'Donald Pleasence'), ('filmTitle', 'The Eagle Has Landed'), ('filmPublicationDate', '1977-05-06T00:00:00Z')]
# [('castMemberName', 'Donald Pleasence'), ('filmTitle', 'The Eagle Has Landed'), ('filmPublicationDate', '1977-08-13T00:00:00Z')]
# [('castMemberName', 'Donald Pleasence'), ('filmTitle', 'The Eagle Has Landed'), ('filmPublicationDate', '1977-11-18T00:00:00Z')]
# [('castMemberName', 'Donald Pleasence'), ('filmTitle', 'The Eagle Has Landed'), ('filmPublicationDate', '1978-03-21T00:00:00Z')]
# [('castMemberName', 'Donald Pleasence'), ('filmTitle', 'The Horsemasters'), ('filmPublicationDate', '1961-10-01T00:00:00Z')]
# [('castMemberName', 'Donald Pleasence'), ('filmTitle', 'Killers of Kilimanjaro'), ('filmPublicationDate', '1959-01-01T00:00:00Z')]
# [('castMemberName', 'Donald Pleasence'), ('filmTitle', 'The Wind Cannot Read'), ('filmPublicationDate', '1958-01-01T00:00:00Z')]
# [('castMemberName', 'Donald Pleasence'), ('filmTitle', 'The Hallelujah Trail'), ('filmPublicationDate', '1965-01-01T00:00:00Z')]
# [('castMemberName', 'Donald Pleasence'), ('filmTitle', 'Fantastic Voyage'), ('filmPublicationDate', '1966-08-24T00:00:00Z')]
# [('castMemberName', 'Donald Pleasence'), ('filmTitle', 'Eye of the Devil'), ('filmPublicationDate', '1966-01-01T00:00:00Z')]
# [('castMemberName', 'Donald Pleasence'), ('filmTitle', 'Blood Relatives'), ('filmPublicationDate', '1978-01-01T00:00:00Z')]
# [('castMemberName', 'Donald Pleasence'), ('filmTitle', 'Blood Relatives'), ('filmPublicationDate', '1978-02-01T00:00:00Z')]
# [('castMemberName', 'Donald Pleasence'), ('filmTitle', 'Sons and Lovers'), ('filmPublicationDate', '1960-01-01T00:00:00Z')]
# [('castMemberName', 'Donald Pleasence'), ('filmTitle', 'Oh, God!'), ('filmPublicationDate', '1977-01-01T00:00:00Z')]
# [('castMemberName', 'Donald Pleasence'), ('filmTitle', 'The Flesh and the Fiends'), ('filmPublicationDate', '1960-01-01T00:00:00Z')]
# [('castMemberName', 'Donald Pleasence'), ('filmTitle', 'Land of the Minotaur'), ('filmPublicationDate', '1976-01-01T00:00:00Z')]
# [('castMemberName', 'Donald Pleasence'), ('filmTitle', 'The Passover Plot'), ('filmPublicationDate', '1976-01-01T00:00:00Z')]
# [('castMemberName', 'Donald Pleasence'), ('filmTitle', 'The Caretaker'), ('filmPublicationDate', '1963-01-01T00:00:00Z')]
# [('castMemberName', 'Donald Pleasence'), ('filmTitle', '1984'), ('filmPublicationDate', '1956-01-01T00:00:00Z')]
# [('castMemberName', 'Donald Pleasence'), ('filmTitle', 'Will Penny'), ('filmPublicationDate', '1968-01-01T00:00:00Z')]
# [('castMemberName', 'Donald Pleasence'), ('filmTitle', 'The Beachcomber'), ('filmPublicationDate', '1954-01-01T00:00:00Z')]
# [('castMemberName', 'Donald Pleasence'), ('filmTitle', 'The Madwoman of Chaillot'), ('filmPublicationDate', '1969-01-01T00:00:00Z')]
# [('castMemberName', 'Donald Pleasence'), ('filmTitle', 'Arthur! Arthur!'), ('filmPublicationDate', '1969-01-01T00:00:00Z')]
# [('castMemberName', 'Donald Pleasence'), ('filmTitle', 'Cul-de-sac'), ('filmPublicationDate', '1966-01-01T00:00:00Z')]
# [('castMemberName', 'Donald Pleasence'), ('filmTitle', 'Kidnapped'), ('filmPublicationDate', '1971-01-01T00:00:00Z')]
# [('castMemberName', 'Donald Pleasence'), ('filmTitle', 'From Beyond the Grave'), ('filmPublicationDate', '1973-01-01T00:00:00Z')]
# [('castMemberName', 'Donald Pleasence'), ('filmTitle', 'What a Carve Up!'), ('filmPublicationDate', '1961-01-01T00:00:00Z')]
# [('castMemberName', 'Donald Pleasence'), ('filmTitle', 'The Other People'), ('filmPublicationDate', '1968-09-01T00:00:00Z')]
# [('castMemberName', 'Donald Pleasence'), ('filmTitle', 'The Uncanny'), ('filmPublicationDate', '1977-01-01T00:00:00Z')]
# [('castMemberName', 'Donald Pleasence'), ('filmTitle', 'The Mutations'), ('filmPublicationDate', '1974-01-01T00:00:00Z')]
# [('castMemberName', 'Donald Pleasence'), ('filmTitle', 'No Love for Johnnie'), ('filmPublicationDate', '1961-01-01T00:00:00Z')]
# [('castMemberName', 'Donald Pleasence'), ('filmTitle', 'Heart of a Child'), ('filmPublicationDate', '1958-01-01T00:00:00Z')]
# [('castMemberName', 'Donald Pleasence'), ('filmTitle', 'Escape to Witch Mountain'), ('filmPublicationDate', '1975-03-21T00:00:00Z')]
# [('castMemberName', 'Donald Pleasence'), ('filmTitle', 'Power Play'), ('filmPublicationDate', '1978-08-25T00:00:00Z')]
# [('castMemberName', 'Donald Pleasence'), ('filmTitle', 'Mr. Freedom'), ('filmPublicationDate', '1969-01-01T00:00:00Z')]
# [('castMemberName', 'Donald Pleasence'), ('filmTitle', 'The Wind of Change'), ('filmPublicationDate', '1961-01-01T00:00:00Z')]
# [('castMemberName', 'Donald Pleasence'), ('filmTitle', 'Wake in Fright'), ('filmPublicationDate', '1971-01-01T00:00:00Z')]
# [('castMemberName', 'Donald Pleasence'), ('filmTitle', 'The Big Day'), ('filmPublicationDate', '1960-07-01T00:00:00Z')]
# [('castMemberName', 'Donald Pleasence'), ('filmTitle', "Sgt. Pepper's Lonely Hearts Club Band"), ('filmPublicationDate', '1978-01-01T00:00:00Z')]
# [('castMemberName', 'Donald Pleasence'), ('filmTitle', "Sgt. Pepper's Lonely Hearts Club Band"), ('filmPublicationDate', '1978-07-21T00:00:00Z')]
# [('castMemberName', 'Donald Pleasence'), ('filmTitle', 'Spare the Rod'), ('filmPublicationDate', '1961-01-01T00:00:00Z')]
# [('castMemberName', 'Donald Pleasence'), ('filmTitle', 'Soldier Blue'), ('filmPublicationDate', '1970-01-01T00:00:00Z')]
# [('castMemberName', 'Donald Pleasence'), ('filmTitle', 'Journey into Fear'), ('filmPublicationDate', '1975-01-01T00:00:00Z')]
# [('castMemberName', 'Donald Pleasence'), ('filmTitle', 'Innocent Bystanders'), ('filmPublicationDate', '1972-01-01T00:00:00Z')]
# [('castMemberName', 'Donald Pleasence'), ('filmTitle', 'The Inspector'), ('filmPublicationDate', '1962-01-01T00:00:00Z')]
# [('castMemberName', 'Donald Pleasence'), ('filmTitle', 'The Jerusalem File'), ('filmPublicationDate', '1972-01-01T00:00:00Z')]
# [('castMemberName', 'Donald Pleasence'), ('filmTitle', 'Death Line'), ('filmPublicationDate', '1972-01-01T00:00:00Z')]
# [('castMemberName', 'Donald Pleasence'), ('filmTitle', "I Don't Want to Be Born"), ('filmPublicationDate', '1975-01-01T00:00:00Z')]
# [('castMemberName', 'Donald Pleasence'), ('filmTitle', 'The Black Tent'), ('filmPublicationDate', '1956-01-01T00:00:00Z')]
# [('castMemberName', 'Donald Pleasence'), ('filmTitle', 'Dr. Crippen'), ('filmPublicationDate', '1962-01-01T00:00:00Z')]
# [('castMemberName', 'Donald Pleasence'), ('filmTitle', 'The Night of the Generals'), ('filmPublicationDate', '1967-01-01T00:00:00Z')]
# [('castMemberName', 'Donald Pleasence'), ('filmTitle', 'Look Back in Anger'), ('filmPublicationDate', '1958-01-01T00:00:00Z')]
# [('castMemberName', 'Donald Pleasence'), ('filmTitle', 'Hearts of the West'), ('filmPublicationDate', '1975-01-01T00:00:00Z')]
# [('castMemberName', 'Donald Pleasence'), ('filmTitle', 'Hell Is a City'), ('filmPublicationDate', '1960-01-01T00:00:00Z')]
# [('castMemberName', 'Donald Pleasence'), ('filmTitle', 'Circus of Horrors'), ('filmPublicationDate', '1960-01-01T00:00:00Z')]
# [('castMemberName', 'Donald Pleasence'), ('filmTitle', 'Out of the Darkness'), ('filmPublicationDate', '1978-01-01T00:00:00Z')]
# [('castMemberName', 'Gabriel Cattand'), ('filmTitle', 'Story of O'), ('filmPublicationDate', '1975-01-01T00:00:00Z')]
# [('castMemberName', 'Gabriel Cattand'), ('filmTitle', 'Story of O'), ('filmPublicationDate', '1975-11-27T00:00:00Z')]
# [('castMemberName', 'John Carpenter'), ('filmTitle', 'Network'), ('filmPublicationDate', '1976-11-14T00:00:00Z')]
# [('castMemberName', 'John Carpenter'), ('filmTitle', 'Network'), ('filmPublicationDate', '1977-03-10T00:00:00Z')]
# [('castMemberName', 'John Carpenter'), ('filmTitle', 'Dark Star'), ('filmPublicationDate', '1974-04-01T00:00:00Z')]
# [('castMemberName', 'John Carpenter'), ('filmTitle', 'Dark Star'), ('filmPublicationDate', '1975-01-16T00:00:00Z')]
# [('castMemberName', 'John Michael Graham'), ('filmTitle', 'Grease'), ('filmPublicationDate', '1978-06-13T00:00:00Z')]
# [('castMemberName', 'John Michael Graham'), ('filmTitle', 'Grease'), ('filmPublicationDate', '1978-09-28T00:00:00Z')]
# [('castMemberName', 'Kyle Richards'), ('filmTitle', 'The Car'), ('filmPublicationDate', '1977-05-13T00:00:00Z')]
# [('castMemberName', 'Kyle Richards'), ('filmTitle', 'Escape to Witch Mountain'), ('filmPublicationDate', '1975-03-21T00:00:00Z')]
# [('castMemberName', 'Kyle Richards'), ('filmTitle', 'Eaten Alive'), ('filmPublicationDate', '1977-01-01T00:00:00Z')]
# [('castMemberName', 'Nancy Kyes'), ('filmTitle', 'Assault on Precinct 13'), ('filmPublicationDate', '1976-01-01T00:00:00Z')]
# [('castMemberName', 'Nick Castle'), ('filmTitle', 'Dark Star'), ('filmPublicationDate', '1974-04-01T00:00:00Z')]
# [('castMemberName', 'Nick Castle'), ('filmTitle', 'Dark Star'), ('filmPublicationDate', '1975-01-16T00:00:00Z')]
# [('castMemberName', 'P. J. Soles'), ('filmTitle', 'The Boy in the Plastic Bubble'), ('filmPublicationDate', '1976-01-01T00:00:00Z')]
# [('castMemberName', 'P. J. Soles'), ('filmTitle', 'Carrie'), ('filmPublicationDate', '1976-11-03T00:00:00Z')]
# [('castMemberName', 'P. J. Soles'), ('filmTitle', 'Carrie'), ('filmPublicationDate', '1977-04-22T00:00:00Z')]
# [('castMemberName', 'P. J. Soles'), ('filmTitle', "Rock 'n' Roll High School"), ('filmPublicationDate', '1978-01-01T00:00:00Z')]
# 136

# %%
# Check who was the most famous actor/actress on Halloween and Friday the 13th at the time of the release
# (e.g., the actor/actress who acted in more movies before and/or the actor/actress who won more academy awards)

queryString = """
SELECT ?filmTitle ?castMemberName ?fameScore
WHERE {

    {
        SELECT DISTINCT ?castMemberName (COUNT(DISTINCT ?film) AS ?fameScore) ?filmTitle
        WHERE { 

            wd:Q221103 wdt:P161 ?castMember.
            wd:Q221103 wdt:P1476 ?filmTitle.

            # ?castMember <http://schema.org/name> ?castMemberName.

            # ?film wdt:P161 ?castMember.
            # ?film wdt:P577 ?filmPublicationDate.
            FILTER(?filmPublicationDate < '1978-10-25T00:00:00Z'^^xsd:dateTime)
        } 
        ORDER BY DESC (?fameScore)
        LIMIT 1
    }
    UNION
    {
        SELECT DISTINCT ?castMemberName (COUNT(DISTINCT ?film) AS ?fameScore) ?filmTitle
        WHERE { 

            wd:Q1243029 wdt:P161 ?castMember.
            wd:Q1243029 wdt:P1476 ?filmTitle.

            # ?castMember <http://schema.org/name> ?castMemberName.

            # ?film wdt:P161 ?castMember.
            # ?film wdt:P577 ?filmPublicationDate.
            FILTER(?filmPublicationDate < '1980-05-09T00:00:00Z'^^xsd:dateTime)
        } 
        ORDER BY DESC (?fameScore)
        LIMIT 1
    }

}


"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('filmTitle', 'Halloween'), ('castMemberName', 'Donald Pleasence'), ('fameScore', '74')]
# [('filmTitle', 'Friday the 13th'), ('castMemberName', 'Betsy Palmer'), ('fameScore', '6')]
# 2

# %% [markdown]
# ### Piont 2 Finish
#
# DESCRIPTION: First I use relation “professions” wdt:P161 to find the “actor” class.
# Then, I started again by taking a general person that as profession is: "actor" wd:Q33999, "character actor" wd:Q948329, "film actor" wd:Q10800557, "stage actor" wd:Q2259451, "television actor" wd:Q10798782 and return all its properties.
# Then I tried a different approach and returned all the ingoing and outgoing properties from the cast members of Halloween and I found the “winner” wdt:P1346 property which connects an award to a person.
# Then I searched for the release dates of both films.
# I try to find a possible way to compute the fame of an actor. I decided to count the number of films and receiver awards. In the end I realize that I was not able to find the date of an award, so I decided to use only the number of films.
#
#
# RESULT: The result shows the most famous actors for the films. The “fameScore” was computed by counting the number of films that they made before the release of Halloween and Friday 13th.

# %% [markdown]
# ### Task 3 Start

# %%
# Get the film done after Halloween by all cast members

queryString = """
SELECT DISTINCT ?castMemberName (COUNT(DISTINCT ?film) AS ?filmAfterRelease)
WHERE { 

    wd:Q221103 wdt:P161 ?castMember.

    # ?castMember <http://schema.org/name> ?castMemberName.

    # ?film wdt:P161 ?castMember.
    # ?film wdt:P577 ?filmPublicationDate.
    FILTER(?filmPublicationDate > '1978-10-25T00:00:00Z'^^xsd:dateTime)
} 
ORDER BY DESC (?filmAfterRelease)
  
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('castMemberName', 'Donald Pleasence'), ('filmAfterRelease', '55')]
# [('castMemberName', 'Jamie Lee Curtis'), ('filmAfterRelease', '52')]
# [('castMemberName', 'P. J. Soles'), ('filmAfterRelease', '20')]
# [('castMemberName', 'John Carpenter'), ('filmAfterRelease', '18')]
# [('castMemberName', 'Gabriel Cattand'), ('filmAfterRelease', '12')]
# [('castMemberName', 'Arthur Malet'), ('filmAfterRelease', '10')]
# [('castMemberName', 'Charles Cyphers'), ('filmAfterRelease', '9')]
# [('castMemberName', 'Kyle Richards'), ('filmAfterRelease', '8')]
# [('castMemberName', 'Nick Castle'), ('filmAfterRelease', '6')]
# [('castMemberName', 'Nancy Kyes'), ('filmAfterRelease', '5')]
# [('castMemberName', 'Nancy Stephens'), ('filmAfterRelease', '4')]
# [('castMemberName', 'Tony Moran'), ('filmAfterRelease', '3')]
# [('castMemberName', 'John Michael Graham'), ('filmAfterRelease', '1')]
# 13

# %%
# Check which actor/actress did more movies after the release of these two films (consider the films separately)

queryString = """
SELECT ?filmTitle ?castMemberName ?filmAfterRelease
WHERE {

    {
        SELECT DISTINCT ?castMemberName (COUNT(DISTINCT ?film) AS ?filmAfterRelease) ?filmTitle
        WHERE { 

            wd:Q221103 wdt:P161 ?castMember.
            wd:Q221103 wdt:P1476 ?filmTitle.

            # ?castMember <http://schema.org/name> ?castMemberName.

            # ?film wdt:P161 ?castMember.
            # ?film wdt:P577 ?filmPublicationDate.
            FILTER(?filmPublicationDate > '1978-10-25T00:00:00Z'^^xsd:dateTime)
        } 
        ORDER BY DESC (?filmAfterRelease)
        LIMIT 1
    }
    UNION
    {
        SELECT DISTINCT ?castMemberName (COUNT(DISTINCT ?film) AS ?filmAfterRelease) ?filmTitle
        WHERE { 

            wd:Q1243029 wdt:P161 ?castMember.
            wd:Q1243029 wdt:P1476 ?filmTitle.

            # ?castMember <http://schema.org/name> ?castMemberName.

            # ?film wdt:P161 ?castMember.
            # ?film wdt:P577 ?filmPublicationDate.
            FILTER(?filmPublicationDate > '1980-05-09T00:00:00Z'^^xsd:dateTime)
        } 
        ORDER BY DESC (?filmAfterRelease)
        LIMIT 1
    }

}


"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('filmTitle', 'Halloween'), ('castMemberName', 'Donald Pleasence'), ('filmAfterRelease', '55')]
# [('filmTitle', 'Friday the 13th'), ('castMemberName', 'Kevin Bacon'), ('filmAfterRelease', '64')]
# 2

# %% [markdown]
# ### Piont 3 Finish
#
# DESCRIPTION: This query is very similar to the previous one but with the opposite filter.
#
# RESULT: The result shows the two actors that did more movies for both films after their release date.

# %% [markdown]
# ### Task 4 Start

# %%
# Return info about "part of the series" property for Halloween node
queryString = """
SELECT DISTINCT ?object ?objectName
WHERE { 

    wd:Q221103 wdt:P179 ?object.
    # ?object <http://schema.org/name> ?objectName.
} 
ORDER BY ?objectName
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('object', 'http://www.wikidata.org/entity/Q1364022'), ('objectName', 'Halloween')]
# 1

# %%
# Return all nodes that are connected to "Halloween" serie  
queryString = """
SELECT DISTINCT ?film ?filmTitle
WHERE { 

    # ?film wdt:P179 wd:Q1364022.
    # ?film wdt:P1476 ?filmTitle.
} 
ORDER BY ?filmTitle
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('film', 'http://www.wikidata.org/entity/Q221103'), ('filmTitle', 'Halloween')]
# [('film', 'http://www.wikidata.org/entity/Q909063'), ('filmTitle', 'Halloween')]
# [('film', 'http://www.wikidata.org/entity/Q959853'), ('filmTitle', 'Halloween 4: The Return of Michael Myers')]
# [('film', 'http://www.wikidata.org/entity/Q976728'), ('filmTitle', 'Halloween 5: The Revenge of Michael Myers')]
# [('film', 'http://www.wikidata.org/entity/Q1050815'), ('filmTitle', 'Halloween H20: 20 Years Later')]
# [('film', 'http://www.wikidata.org/entity/Q850312'), ('filmTitle', 'Halloween II')]
# [('film', 'http://www.wikidata.org/entity/Q908690'), ('filmTitle', 'Halloween II')]
# [('film', 'http://www.wikidata.org/entity/Q203705'), ('filmTitle', 'Halloween III: Season of the Witch')]
# [('film', 'http://www.wikidata.org/entity/Q176488'), ('filmTitle', 'Halloween: Resurrection')]
# [('film', 'http://www.wikidata.org/entity/Q1138055'), ('filmTitle', 'Halloween: The Curse of Michael Myers')]
# 10

# %%
# Return all films of Halloween franchise with year
queryString = """
SELECT DISTINCT ?film ?filmTitle (MIN(?outYear) AS ?year)
WHERE { 

    # ?film wdt:P179 wd:Q1364022.
    # ?film wdt:P1476 ?filmTitle.
    # ?film wdt:P577 ?publicationDate.
    BIND(YEAR(?publicationDate) AS ?outYear)
} 
ORDER BY (?year)
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('film', 'http://www.wikidata.org/entity/Q221103'), ('filmTitle', 'Halloween'), ('year', '1978')]
# [('film', 'http://www.wikidata.org/entity/Q850312'), ('filmTitle', 'Halloween II'), ('year', '1981')]
# [('film', 'http://www.wikidata.org/entity/Q203705'), ('filmTitle', 'Halloween III: Season of the Witch'), ('year', '1982')]
# [('film', 'http://www.wikidata.org/entity/Q959853'), ('filmTitle', 'Halloween 4: The Return of Michael Myers'), ('year', '1988')]
# [('film', 'http://www.wikidata.org/entity/Q976728'), ('filmTitle', 'Halloween 5: The Revenge of Michael Myers'), ('year', '1989')]
# [('film', 'http://www.wikidata.org/entity/Q1138055'), ('filmTitle', 'Halloween: The Curse of Michael Myers'), ('year', '1995')]
# [('film', 'http://www.wikidata.org/entity/Q1050815'), ('filmTitle', 'Halloween H20: 20 Years Later'), ('year', '1998')]
# [('film', 'http://www.wikidata.org/entity/Q176488'), ('filmTitle', 'Halloween: Resurrection'), ('year', '2002')]
# [('film', 'http://www.wikidata.org/entity/Q909063'), ('filmTitle', 'Halloween'), ('year', '2007')]
# [('film', 'http://www.wikidata.org/entity/Q908690'), ('filmTitle', 'Halloween II'), ('year', '2009')]
# 10

# %%
# Return all films of Halloween franchise with year and director
queryString = """
SELECT DISTINCT ?film ?filmTitle (MIN(?outYear) AS ?year) (GROUP_CONCAT(DISTINCT ?directorName; separator=" ,") AS ?directors)
WHERE { 

    # ?film wdt:P179 wd:Q1364022.
    # ?film wdt:P1476 ?filmTitle.
    
    # ?film wdt:P57 ?director.
    # ?director <http://schema.org/name> ?directorName.
    
    # ?film wdt:P577 ?publicationDate.
    BIND(YEAR(?publicationDate) AS ?outYear)
} 
ORDER BY (?year)
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('film', 'http://www.wikidata.org/entity/Q221103'), ('filmTitle', 'Halloween'), ('year', '1978'), ('directors', 'John Carpenter')]
# [('film', 'http://www.wikidata.org/entity/Q850312'), ('filmTitle', 'Halloween II'), ('year', '1981'), ('directors', 'John Carpenter ,Rick Rosenthal')]
# [('film', 'http://www.wikidata.org/entity/Q203705'), ('filmTitle', 'Halloween III: Season of the Witch'), ('year', '1982'), ('directors', 'Tommy Lee Wallace')]
# [('film', 'http://www.wikidata.org/entity/Q959853'), ('filmTitle', 'Halloween 4: The Return of Michael Myers'), ('year', '1988'), ('directors', 'Dwight H. Little')]
# [('film', 'http://www.wikidata.org/entity/Q976728'), ('filmTitle', 'Halloween 5: The Revenge of Michael Myers'), ('year', '1989'), ('directors', 'Dominique Othenin-Girard')]
# [('film', 'http://www.wikidata.org/entity/Q1138055'), ('filmTitle', 'Halloween: The Curse of Michael Myers'), ('year', '1995'), ('directors', 'Joe Chappelle')]
# [('film', 'http://www.wikidata.org/entity/Q1050815'), ('filmTitle', 'Halloween H20: 20 Years Later'), ('year', '1998'), ('directors', 'Steve Miner')]
# [('film', 'http://www.wikidata.org/entity/Q176488'), ('filmTitle', 'Halloween: Resurrection'), ('year', '2002'), ('directors', 'Rick Rosenthal')]
# [('film', 'http://www.wikidata.org/entity/Q909063'), ('filmTitle', 'Halloween'), ('year', '2007'), ('directors', 'Rob Zombie')]
# [('film', 'http://www.wikidata.org/entity/Q908690'), ('filmTitle', 'Halloween II'), ('year', '2009'), ('directors', 'Rob Zombie')]
# 10

# %%
# Return info about "part of the series" property for Friday the 13th node
queryString = """
SELECT DISTINCT ?object ?objectName
WHERE { 

    wd:Q1243029 wdt:P179 ?object.
    # ?object <http://schema.org/name> ?objectName.
    
} 
ORDER BY ?objectName
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('object', 'http://www.wikidata.org/entity/Q1138878'), ('objectName', 'Friday the 13th')]
# 1

# %%
# Return all films of Friday the 13th franchise with year and director
queryString = """
SELECT DISTINCT ?film ?filmTitle (MIN(?outYear) AS ?year) (GROUP_CONCAT(DISTINCT ?directorName; separator=" ,") AS ?directors)
WHERE { 

    # ?film wdt:P179 wd:Q1138878.
    # ?film wdt:P1476 ?filmTitle.
    
    # ?film wdt:P57 ?director.
    # ?director <http://schema.org/name> ?directorName.
    
    # ?film wdt:P577 ?publicationDate.
    BIND(YEAR(?publicationDate) AS ?outYear)
} 
ORDER BY (?year)
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('film', 'http://www.wikidata.org/entity/Q1243029'), ('filmTitle', 'Friday the 13th'), ('year', '1980'), ('directors', 'Sean S. Cunningham')]
# [('film', 'http://www.wikidata.org/entity/Q1243009'), ('filmTitle', 'Friday the 13th Part 2'), ('year', '1981'), ('directors', 'Sean S. Cunningham ,Steve Miner')]
# [('film', 'http://www.wikidata.org/entity/Q1243013'), ('filmTitle', 'Friday the 13th Part III'), ('year', '1982'), ('directors', 'Steve Miner')]
# [('film', 'http://www.wikidata.org/entity/Q1243019'), ('filmTitle', 'Friday the 13th: The Final Chapter'), ('year', '1984'), ('directors', 'Joseph Zito')]
# [('film', 'http://www.wikidata.org/entity/Q286830'), ('filmTitle', 'Friday the 13th: A New Beginning'), ('year', '1985'), ('directors', 'Danny Steinmann')]
# [('film', 'http://www.wikidata.org/entity/Q1454799'), ('filmTitle', 'Friday the 13th Part VI: Jason Lives'), ('year', '1986'), ('directors', 'Tom McLoughlin')]
# [('film', 'http://www.wikidata.org/entity/Q1454798'), ('filmTitle', 'Friday the 13th Part VII: The New Blood'), ('year', '1988'), ('directors', 'John Carl Buechler')]
# [('film', 'http://www.wikidata.org/entity/Q1454794'), ('filmTitle', 'Friday the 13th Part VIII: Jason Takes Manhattan'), ('year', '1989'), ('directors', 'Rob Hedden')]
# [('film', 'http://www.wikidata.org/entity/Q1683918'), ('filmTitle', 'Jason Goes to Hell: The Final Friday'), ('year', '1993'), ('directors', 'Adam Marcus')]
# [('film', 'http://www.wikidata.org/entity/Q1427521'), ('filmTitle', 'Jason X'), ('year', '2001'), ('directors', 'James Isaac')]
# [('film', 'http://www.wikidata.org/entity/Q965859'), ('filmTitle', 'Freddy vs. Jason'), ('year', '2003'), ('directors', 'Ronny Yu')]
# [('film', 'http://www.wikidata.org/entity/Q1454815'), ('filmTitle', 'Friday the 13th'), ('year', '2009'), ('directors', 'Marcus Nispel')]
# 12

# %%
# Get all the movies of the two franchises (return year and director)
queryString = """
SELECT DISTINCT ?film ?franchiseName ?filmTitle (MIN(?outYear) AS ?year) (GROUP_CONCAT(DISTINCT ?directorName; separator=" ,") AS ?directors)
WHERE { 

    {
        # ?film wdt:P179 wd:Q1364022.
        # ?film wdt:P1476 ?filmTitle.
        wd:Q1364022 <http://schema.org/name> ?franchiseName.

        # ?film wdt:P57 ?director.
        # ?director <http://schema.org/name> ?directorName.

        # ?film wdt:P577 ?publicationDate.
        BIND(YEAR(?publicationDate) AS ?outYear)
    }
    UNION
    {
        # ?film wdt:P179 wd:Q1138878.
        # ?film wdt:P1476 ?filmTitle.
        wd:Q1138878 <http://schema.org/name> ?franchiseName.

        # ?film wdt:P57 ?director.
        # ?director <http://schema.org/name> ?directorName.

        # ?film wdt:P577 ?publicationDate.
        BIND(YEAR(?publicationDate) AS ?outYear)
    }
} 
ORDER BY ?franchiseName ?year
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('film', 'http://www.wikidata.org/entity/Q1243029'), ('franchiseName', 'Friday the 13th'), ('filmTitle', 'Friday the 13th'), ('year', '1980'), ('directors', 'Sean S. Cunningham')]
# [('film', 'http://www.wikidata.org/entity/Q1243009'), ('franchiseName', 'Friday the 13th'), ('filmTitle', 'Friday the 13th Part 2'), ('year', '1981'), ('directors', 'Sean S. Cunningham ,Steve Miner')]
# [('film', 'http://www.wikidata.org/entity/Q1243013'), ('franchiseName', 'Friday the 13th'), ('filmTitle', 'Friday the 13th Part III'), ('year', '1982'), ('directors', 'Steve Miner')]
# [('film', 'http://www.wikidata.org/entity/Q1243019'), ('franchiseName', 'Friday the 13th'), ('filmTitle', 'Friday the 13th: The Final Chapter'), ('year', '1984'), ('directors', 'Joseph Zito')]
# [('film', 'http://www.wikidata.org/entity/Q286830'), ('franchiseName', 'Friday the 13th'), ('filmTitle', 'Friday the 13th: A New Beginning'), ('year', '1985'), ('directors', 'Danny Steinmann')]
# [('film', 'http://www.wikidata.org/entity/Q1454799'), ('franchiseName', 'Friday the 13th'), ('filmTitle', 'Friday the 13th Part VI: Jason Lives'), ('year', '1986'), ('directors', 'Tom McLoughlin')]
# [('film', 'http://www.wikidata.org/entity/Q1454798'), ('franchiseName', 'Friday the 13th'), ('filmTitle', 'Friday the 13th Part VII: The New Blood'), ('year', '1988'), ('directors', 'John Carl Buechler')]
# [('film', 'http://www.wikidata.org/entity/Q1454794'), ('franchiseName', 'Friday the 13th'), ('filmTitle', 'Friday the 13th Part VIII: Jason Takes Manhattan'), ('year', '1989'), ('directors', 'Rob Hedden')]
# [('film', 'http://www.wikidata.org/entity/Q1683918'), ('franchiseName', 'Friday the 13th'), ('filmTitle', 'Jason Goes to Hell: The Final Friday'), ('year', '1993'), ('directors', 'Adam Marcus')]
# [('film', 'http://www.wikidata.org/entity/Q1427521'), ('franchiseName', 'Friday the 13th'), ('filmTitle', 'Jason X'), ('year', '2001'), ('directors', 'James Isaac')]
# [('film', 'http://www.wikidata.org/entity/Q965859'), ('franchiseName', 'Friday the 13th'), ('filmTitle', 'Freddy vs. Jason'), ('year', '2003'), ('directors', 'Ronny Yu')]
# [('film', 'http://www.wikidata.org/entity/Q1454815'), ('franchiseName', 'Friday the 13th'), ('filmTitle', 'Friday the 13th'), ('year', '2009'), ('directors', 'Marcus Nispel')]
# [('film', 'http://www.wikidata.org/entity/Q221103'), ('franchiseName', 'Halloween'), ('filmTitle', 'Halloween'), ('year', '1978'), ('directors', 'John Carpenter')]
# [('film', 'http://www.wikidata.org/entity/Q850312'), ('franchiseName', 'Halloween'), ('filmTitle', 'Halloween II'), ('year', '1981'), ('directors', 'John Carpenter ,Rick Rosenthal')]
# [('film', 'http://www.wikidata.org/entity/Q203705'), ('franchiseName', 'Halloween'), ('filmTitle', 'Halloween III: Season of the Witch'), ('year', '1982'), ('directors', 'Tommy Lee Wallace')]
# [('film', 'http://www.wikidata.org/entity/Q959853'), ('franchiseName', 'Halloween'), ('filmTitle', 'Halloween 4: The Return of Michael Myers'), ('year', '1988'), ('directors', 'Dwight H. Little')]
# [('film', 'http://www.wikidata.org/entity/Q976728'), ('franchiseName', 'Halloween'), ('filmTitle', 'Halloween 5: The Revenge of Michael Myers'), ('year', '1989'), ('directors', 'Dominique Othenin-Girard')]
# [('film', 'http://www.wikidata.org/entity/Q1138055'), ('franchiseName', 'Halloween'), ('filmTitle', 'Halloween: The Curse of Michael Myers'), ('year', '1995'), ('directors', 'Joe Chappelle')]
# [('film', 'http://www.wikidata.org/entity/Q1050815'), ('franchiseName', 'Halloween'), ('filmTitle', 'Halloween H20: 20 Years Later'), ('year', '1998'), ('directors', 'Steve Miner')]
# [('film', 'http://www.wikidata.org/entity/Q176488'), ('franchiseName', 'Halloween'), ('filmTitle', 'Halloween: Resurrection'), ('year', '2002'), ('directors', 'Rick Rosenthal')]
# [('film', 'http://www.wikidata.org/entity/Q909063'), ('franchiseName', 'Halloween'), ('filmTitle', 'Halloween'), ('year', '2007'), ('directors', 'Rob Zombie')]
# [('film', 'http://www.wikidata.org/entity/Q908690'), ('franchiseName', 'Halloween'), ('filmTitle', 'Halloween II'), ('year', '2009'), ('directors', 'Rob Zombie')]
# 22

# %% [markdown]
# ### Piont 4 Finish
#
# DESCRIPTION: First I try to understand more about “part of the series” wdt:P179 property. And find the entity “Halloween” wd:Q1364022 that represents the Halloween film series. From this I returned all films that are part of it. Then from all these films I returned their year and director’s name. I proceed finding the series for “Friday the 13th “ wdt:Q1138878.
# Then I combine the results and obtain what the point asks. Notice that for release date I consider the earliest one for every film.
#
#
# RESULT: The result shows that Friday the 13th has twelve films while Halloween series has ten films. It is also possible to see the release date and the director’s name of every single film.

# %% [markdown]
# ### Task 5 Start

# %%
# Return all workers involved in Halloween franchises with their role
queryString = """
SELECT ?workerName (GROUP_CONCAT(DISTINCT ?filmTitle; separator=" ,") AS ?workedIn) (GROUP_CONCAT(?propertyName; separator=" ,") AS ?roles)
WHERE { 


    # ?film wdt:P179 wd:Q1364022.
    # ?film wdt:P1476 ?filmTitle.
    wd:Q1364022 <http://schema.org/name> ?franchiseName.
    
    # ?film ?property ?worker.
    # ?worker <http://schema.org/name> ?workerName.
    
    # ?property <http://schema.org/name> ?propertyName.
    FILTER(?property = wdt:P161 || ?property = wdt:P57 || ?property = wdt:P344 || ?property = wdt:P175 
    || ?property = wdt:P162 || ?property = wdt:2554 || ?property = wdt:P58 || ?property = wdt:P86 || ?property = wdt:P1431)



} 
GROUP BY ?workerName
ORDER BY ?workerName
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('workerName', '"Weird Al" Yankovic'), ('workedIn', 'Halloween II'), ('roles', 'cast member')]
# [('workerName', 'Adam Arkin'), ('workedIn', 'Halloween H20: 20 Years Later'), ('roles', 'cast member')]
# [('workerName', 'Adam Hann-Byrd'), ('workedIn', 'Halloween H20: 20 Years Later'), ('roles', 'cast member')]
# [('workerName', 'Adam Weisman'), ('workedIn', 'Halloween'), ('roles', 'cast member')]
# [('workerName', 'Alan B. McElroy'), ('workedIn', 'Halloween 4: The Return of Michael Myers'), ('roles', 'screenwriter')]
# [('workerName', 'Alan Howarth'), ('workedIn', 'Halloween 4: The Return of Michael Myers ,Halloween 5: The Revenge of Michael Myers ,Halloween III: Season of the Witch ,Halloween: The Curse of Michael Myers'), ('roles', 'composer ,composer ,composer ,composer')]
# [('workerName', 'Ana Alicia'), ('workedIn', 'Halloween II'), ('roles', 'cast member')]
# [('workerName', 'Angela Trimbur'), ('workedIn', 'Halloween II'), ('roles', 'cast member')]
# [('workerName', 'Anne-Marie Martin'), ('workedIn', 'Halloween II'), ('roles', 'cast member')]
# [('workerName', 'Arthur Malet'), ('workedIn', 'Halloween'), ('roles', 'cast member')]
# [('workerName', 'Beau Billingslea'), ('workedIn', 'Halloween H20: 20 Years Later'), ('roles', 'cast member')]
# [('workerName', 'Beau Starr'), ('workedIn', 'Halloween 4: The Return of Michael Myers ,Halloween 5: The Revenge of Michael Myers'), ('roles', 'cast member ,cast member')]
# [('workerName', 'Betsy Rue'), ('workedIn', 'Halloween II'), ('roles', 'cast member')]
# [('workerName', 'Bianca Kajlich'), ('workedIn', 'Halloween: Resurrection'), ('roles', 'cast member')]
# [('workerName', 'Bill Fagerbakke'), ('workedIn', 'Halloween II'), ('roles', 'cast member')]
# [('workerName', 'Bill Moseley'), ('workedIn', 'Halloween'), ('roles', 'cast member')]
# [('workerName', 'Billy Dickson'), ('workedIn', 'Halloween: The Curse of Michael Myers'), ('roles', 'director of photography')]
# [('workerName', 'Billy Kay'), ('workedIn', 'Halloween: Resurrection'), ('roles', 'cast member')]
# [('workerName', 'Billy Warlock'), ('workedIn', 'Halloween II'), ('roles', 'cast member')]
# [('workerName', 'Bob Weinstein'), ('workedIn', 'Halloween'), ('roles', 'executive producer')]
# [('workerName', 'Brad Dourif'), ('workedIn', 'Halloween ,Halloween II'), ('roles', 'cast member ,cast member')]
# [('workerName', 'Brad Loree'), ('workedIn', 'Halloween: Resurrection'), ('roles', 'cast member')]
# [('workerName', 'Branden Williams'), ('workedIn', 'Halloween H20: 20 Years Later'), ('roles', 'cast member')]
# [('workerName', 'Brandon Trost'), ('workedIn', 'Halloween II'), ('roles', 'director of photography')]
# [('workerName', 'Brea Grant'), ('workedIn', 'Halloween II'), ('roles', 'cast member')]
# [('workerName', 'Brent Chapman'), ('workedIn', 'Halloween: Resurrection'), ('roles', 'cast member')]
# [('workerName', 'Busta Rhymes'), ('workedIn', 'Halloween: Resurrection'), ('roles', 'cast member')]
# [('workerName', 'Carmen Filpi'), ('workedIn', 'Halloween 4: The Return of Michael Myers'), ('roles', 'cast member')]
# [('workerName', 'Caroline Williams'), ('workedIn', 'Halloween II'), ('roles', 'cast member')]
# [('workerName', 'Charles Cyphers'), ('workedIn', 'Halloween ,Halloween II'), ('roles', 'cast member ,cast member')]
# [('workerName', 'Chase Wright Vanek'), ('workedIn', 'Halloween II'), ('roles', 'cast member')]
# [('workerName', 'Chris Durand'), ('workedIn', 'Halloween H20: 20 Years Later'), ('roles', 'cast member')]
# [('workerName', 'Chris Hardwick'), ('workedIn', 'Halloween II'), ('roles', 'cast member')]
# [('workerName', 'Cliff Emmich'), ('workedIn', 'Halloween II'), ('roles', 'cast member')]
# [('workerName', 'Clint Howard'), ('workedIn', 'Halloween'), ('roles', 'cast member')]
# [('workerName', 'Daeg Faerch'), ('workedIn', 'Halloween'), ('roles', 'cast member')]
# [('workerName', 'Daisy McCrackin'), ('workedIn', 'Halloween: Resurrection'), ('roles', 'cast member')]
# [('workerName', 'Dan Joffre'), ('workedIn', 'Halloween: Resurrection'), ('roles', 'cast member')]
# [('workerName', "Dan O'Herlihy"), ('workedIn', 'Halloween III: Season of the Witch'), ('roles', 'cast member')]
# [('workerName', 'Dana Carvey'), ('workedIn', 'Halloween II'), ('roles', 'cast member')]
# [('workerName', 'Daniel Farrands'), ('workedIn', 'Halloween: The Curse of Michael Myers'), ('roles', 'screenwriter')]
# [('workerName', 'Daniel Roebuck'), ('workedIn', 'Halloween ,Halloween II'), ('roles', 'cast member ,cast member')]
# [('workerName', 'Danielle Harris'), ('workedIn', 'Halloween ,Halloween 4: The Return of Michael Myers ,Halloween 5: The Revenge of Michael Myers ,Halloween II'), ('roles', 'cast member ,cast member ,cast member ,cast member')]
# [('workerName', 'Danny Lux'), ('workedIn', 'Halloween: Resurrection'), ('roles', 'composer')]
# [('workerName', 'Danny Trejo'), ('workedIn', 'Halloween'), ('roles', 'cast member')]
# [('workerName', 'Daryl Sabara'), ('workedIn', 'Halloween'), ('roles', 'cast member')]
# [('workerName', 'Daryn Okada'), ('workedIn', 'Halloween H20: 20 Years Later'), ('roles', 'director of photography')]
# [('workerName', 'David Geddes'), ('workedIn', 'Halloween: Resurrection'), ('roles', 'director of photography')]
# [('workerName', 'Dayton Callie'), ('workedIn', 'Halloween II'), ('roles', 'cast member')]
# [('workerName', 'Dean Cundey'), ('workedIn', 'Halloween ,Halloween II ,Halloween III: Season of the Witch'), ('roles', 'director of photography ,director of photography ,director of photography')]
# [('workerName', 'Debra Hill'), ('workedIn', 'Halloween ,Halloween II ,Halloween III: Season of the Witch'), ('roles', 'producer ,producer ,producer ,screenwriter ,screenwriter ,screenwriter')]
# [('workerName', 'Dee Wallace'), ('workedIn', 'Halloween'), ('roles', 'cast member')]
# [('workerName', 'Dick Warlock'), ('workedIn', 'Halloween II ,Halloween III: Season of the Witch'), ('roles', 'cast member ,cast member')]
# [('workerName', 'Dominique Othenin-Girard'), ('workedIn', 'Halloween 5: The Revenge of Michael Myers'), ('roles', 'director ,screenwriter')]
# [('workerName', 'Don Shanks'), ('workedIn', 'Halloween 5: The Revenge of Michael Myers'), ('roles', 'cast member')]
# [('workerName', 'Donald Pleasence'), ('workedIn', 'Halloween ,Halloween 4: The Return of Michael Myers ,Halloween 5: The Revenge of Michael Myers ,Halloween II ,Halloween: The Curse of Michael Myers'), ('roles', 'cast member ,cast member ,cast member ,cast member ,cast member')]
# [('workerName', 'Duane Whitaker'), ('workedIn', 'Halloween II'), ('roles', 'cast member')]
# [('workerName', 'Dwight H. Little'), ('workedIn', 'Halloween 4: The Return of Michael Myers'), ('roles', 'director')]
# [('workerName', 'Ellie Cornell'), ('workedIn', 'Halloween 4: The Return of Michael Myers ,Halloween 5: The Revenge of Michael Myers'), ('roles', 'cast member ,cast member')]
# [('workerName', 'Ford Rainey'), ('workedIn', 'Halloween II'), ('roles', 'cast member')]
# [('workerName', 'Gabriel Cattand'), ('workedIn', 'Halloween'), ('roles', 'cast member')]
# [('workerName', 'George P. Wilbur'), ('workedIn', 'Halloween 4: The Return of Michael Myers ,Halloween: The Curse of Michael Myers'), ('roles', 'cast member ,cast member')]
# [('workerName', 'Greg Travis'), ('workedIn', 'Halloween II'), ('roles', 'cast member')]
# [('workerName', 'Gregory Nicotero'), ('workedIn', 'Halloween 5: The Revenge of Michael Myers'), ('roles', 'cast member')]
# [('workerName', 'Hanna R. Hall'), ('workedIn', 'Halloween'), ('roles', 'cast member')]
# [('workerName', 'Howard Hesseman'), ('workedIn', 'Halloween II'), ('roles', 'cast member')]
# [('workerName', 'Irwin Yablans'), ('workedIn', 'Halloween'), ('roles', 'producer')]
# [('workerName', 'Jamie Lee Curtis'), ('workedIn', 'Halloween ,Halloween H20: 20 Years Later ,Halloween II ,Halloween III: Season of the Witch ,Halloween: Resurrection'), ('roles', 'cast member ,cast member ,cast member ,cast member ,cast member')]
# [('workerName', 'Janet Leigh'), ('workedIn', 'Halloween H20: 20 Years Later'), ('roles', 'cast member')]
# [('workerName', 'Jeff Daniel Phillips'), ('workedIn', 'Halloween II'), ('roles', 'cast member ,cast member')]
# [('workerName', "Jodi Lyn O'Keefe"), ('workedIn', 'Halloween H20: 20 Years Later'), ('roles', 'cast member')]
# [('workerName', 'Joe Chappelle'), ('workedIn', 'Halloween: The Curse of Michael Myers'), ('roles', 'director')]
# [('workerName', 'John Carpenter'), ('workedIn', 'Halloween ,Halloween 5: The Revenge of Michael Myers ,Halloween II ,Halloween III: Season of the Witch'), ('roles', 'cast member ,producer ,producer ,performer ,director ,director ,screenwriter ,screenwriter ,screenwriter ,screenwriter ,composer ,composer ,composer')]
# [('workerName', 'John Cassini'), ('workedIn', 'Halloween H20: 20 Years Later'), ('roles', 'cast member')]
# [('workerName', 'John MacBride'), ('workedIn', 'Halloween III: Season of the Witch'), ('roles', 'cast member')]
# [('workerName', 'John Michael Graham'), ('workedIn', 'Halloween'), ('roles', 'cast member')]
# [('workerName', 'John Ottman'), ('workedIn', 'Halloween H20: 20 Years Later'), ('roles', 'composer')]
# [('workerName', 'Jonathan Prince'), ('workedIn', 'Halloween II'), ('roles', 'cast member')]
# [('workerName', 'Joseph Gordon-Levitt'), ('workedIn', 'Halloween H20: 20 Years Later'), ('roles', 'cast member')]
# [('workerName', 'Josh Hartnett'), ('workedIn', 'Halloween H20: 20 Years Later'), ('roles', 'cast member')]
# [('workerName', 'Joshua John Miller'), ('workedIn', 'Halloween III: Season of the Witch'), ('roles', 'cast member')]
# [('workerName', 'Katee Sackhoff'), ('workedIn', 'Halloween: Resurrection'), ('roles', 'cast member')]
# [('workerName', 'Kathleen Kinmont'), ('workedIn', 'Halloween 4: The Return of Michael Myers'), ('roles', 'cast member')]
# [('workerName', 'Ken Foree'), ('workedIn', 'Halloween'), ('roles', 'cast member')]
# [('workerName', 'Kim Darby'), ('workedIn', 'Halloween: The Curse of Michael Myers'), ('roles', 'cast member')]
# [('workerName', 'Kristina Klebe'), ('workedIn', 'Halloween'), ('roles', 'cast member')]
# [('workerName', 'Kyle Labine'), ('workedIn', 'Halloween: Resurrection'), ('roles', 'cast member')]
# [('workerName', 'Kyle Richards'), ('workedIn', 'Halloween ,Halloween II'), ('roles', 'cast member ,cast member')]
# [('workerName', 'LL Cool J'), ('workedIn', 'Halloween H20: 20 Years Later'), ('roles', 'cast member')]
# [('workerName', 'Lance Guest'), ('workedIn', 'Halloween II'), ('roles', 'cast member')]
# [('workerName', 'Leo Rossi'), ('workedIn', 'Halloween II'), ('roles', 'cast member')]
# [('workerName', 'Leslie Easterbrook'), ('workedIn', 'Halloween'), ('roles', 'cast member')]
# [('workerName', 'Lew Temple'), ('workedIn', 'Halloween'), ('roles', 'cast member')]
# [('workerName', 'LisaGay Hamilton'), ('workedIn', 'Halloween H20: 20 Years Later'), ('roles', 'cast member')]
# [('workerName', 'Lorena Gale'), ('workedIn', 'Halloween: Resurrection'), ('roles', 'cast member')]
# [('workerName', 'Luke Kirby'), ('workedIn', 'Halloween: Resurrection'), ('roles', 'cast member')]
# [('workerName', 'Maidie Norman'), ('workedIn', 'Halloween III: Season of the Witch'), ('roles', 'cast member')]
# [('workerName', 'Malcolm McDowell'), ('workedIn', 'Halloween ,Halloween II'), ('roles', 'cast member ,cast member')]
# [('workerName', 'Margot Kidder'), ('workedIn', 'Halloween II'), ('roles', 'cast member')]
# [('workerName', "Mariah O'Brien"), ('workedIn', 'Halloween: The Curse of Michael Myers'), ('roles', 'cast member')]
# [('workerName', 'Marianne Hagan'), ('workedIn', 'Halloween: The Curse of Michael Myers'), ('roles', 'cast member')]
# [('workerName', 'Mark Boone Junior'), ('workedIn', 'Halloween II'), ('roles', 'cast member')]
# [('workerName', 'Mark Christopher Lawrence'), ('workedIn', 'Halloween II'), ('roles', 'cast member')]
# [('workerName', 'Mary Birdsong'), ('workedIn', 'Halloween II'), ('roles', 'cast member')]
# [('workerName', 'Matt Bush'), ('workedIn', 'Halloween II'), ('roles', 'cast member')]
# [('workerName', 'Matt Greenberg'), ('workedIn', 'Halloween H20: 20 Years Later'), ('roles', 'screenwriter')]
# [('workerName', 'Matt Winston'), ('workedIn', 'Halloween H20: 20 Years Later'), ('roles', 'cast member')]
# [('workerName', 'Matthew Walker'), ('workedIn', 'Halloween 5: The Revenge of Michael Myers'), ('roles', 'cast member')]
# [('workerName', 'Max Van Ville'), ('workedIn', 'Halloween'), ('roles', 'cast member')]
# [('workerName', 'Michael Currie'), ('workedIn', 'Halloween III: Season of the Witch'), ('roles', 'cast member')]
# [('workerName', 'Michael Pataki'), ('workedIn', 'Halloween 4: The Return of Michael Myers'), ('roles', 'cast member')]
# [('workerName', 'Michelle Williams'), ('workedIn', 'Halloween H20: 20 Years Later'), ('roles', 'cast member')]
# [('workerName', 'Micky Dolenz'), ('workedIn', 'Halloween'), ('roles', 'cast member')]
# [('workerName', 'Mitchell Ryan'), ('workedIn', 'Halloween: The Curse of Michael Myers'), ('roles', 'cast member')]
# [('workerName', 'Moustapha Akkad'), ('workedIn', 'Halloween ,Halloween 4: The Return of Michael Myers ,Halloween 5: The Revenge of Michael Myers ,Halloween III: Season of the Witch ,Halloween: The Curse of Michael Myers'), ('roles', 'producer ,producer ,producer ,producer ,executive producer ,executive producer ,executive producer')]
# [('workerName', 'Nancy Kyes'), ('workedIn', 'Halloween ,Halloween II ,Halloween III: Season of the Witch'), ('roles', 'cast member ,cast member ,cast member')]
# [('workerName', 'Nancy Stephens'), ('workedIn', 'Halloween ,Halloween H20: 20 Years Later ,Halloween II'), ('roles', 'cast member ,cast member ,cast member')]
# [('workerName', 'Natassia Malthe'), ('workedIn', 'Halloween: Resurrection'), ('roles', 'cast member')]
# [('workerName', 'Nick Castle'), ('workedIn', 'Halloween'), ('roles', 'cast member')]
# [('workerName', 'Nick Mennell'), ('workedIn', 'Halloween'), ('roles', 'cast member')]
# [('workerName', 'Nicky Whelan'), ('workedIn', 'Halloween II'), ('roles', 'cast member')]
# [('workerName', 'Octavia Spencer'), ('workedIn', 'Halloween II'), ('roles', 'cast member')]
# [('workerName', 'P. J. Soles'), ('workedIn', 'Halloween'), ('roles', 'cast member')]
# [('workerName', 'Paddi Edwards'), ('workedIn', 'Halloween III: Season of the Witch'), ('roles', 'cast member')]
# [('workerName', 'Pamela Susan Shoop'), ('workedIn', 'Halloween II'), ('roles', 'cast member')]
# [('workerName', 'Pat Skipper'), ('workedIn', 'Halloween'), ('roles', 'cast member')]
# [('workerName', 'Paul Freeman'), ('workedIn', 'Halloween 4: The Return of Michael Myers ,Halloween H20: 20 Years Later ,Halloween: Resurrection ,Halloween: The Curse of Michael Myers'), ('roles', 'producer ,producer ,producer ,producer')]
# [('workerName', 'Paul Rudd'), ('workedIn', 'Halloween: The Curse of Michael Myers'), ('roles', 'cast member')]
# [('workerName', 'Peter Lyons Collister'), ('workedIn', 'Halloween 4: The Return of Michael Myers'), ('roles', 'director of photography')]
# [('workerName', 'Phil Parmet'), ('workedIn', 'Halloween'), ('roles', 'director of photography')]
# [('workerName', 'Rachel Galvin'), ('workedIn', 'Halloween H20: 20 Years Later'), ('roles', 'cast member')]
# [('workerName', 'Ralph Strait'), ('workedIn', 'Halloween III: Season of the Witch'), ('roles', 'cast member')]
# [('workerName', 'Richard Brake'), ('workedIn', 'Halloween II'), ('roles', 'cast member')]
# [('workerName', 'Richard Lynch'), ('workedIn', 'Halloween'), ('roles', 'cast member')]
# [('workerName', 'Richard Riehle'), ('workedIn', 'Halloween II'), ('roles', 'cast member')]
# [('workerName', 'Rick Rosenthal'), ('workedIn', 'Halloween II ,Halloween: Resurrection'), ('roles', 'cast member ,director ,director')]
# [('workerName', 'Rob Zombie'), ('workedIn', 'Halloween ,Halloween II'), ('roles', 'producer ,producer ,director ,director ,screenwriter ,screenwriter')]
# [('workerName', 'Robert Curtis Brown'), ('workedIn', 'Halloween II'), ('roles', 'cast member')]
# [('workerName', 'Robert Draper'), ('workedIn', 'Halloween 5: The Revenge of Michael Myers'), ('roles', 'director of photography')]
# [('workerName', 'Roland Ménard'), ('workedIn', 'Halloween III: Season of the Witch'), ('roles', 'cast member')]
# [('workerName', 'Ryan McDonald'), ('workedIn', 'Halloween: Resurrection'), ('roles', 'cast member')]
# [('workerName', 'Ryan Merriman'), ('workedIn', 'Halloween: Resurrection'), ('roles', 'cast member')]
# [('workerName', 'Sasha Jenson'), ('workedIn', 'Halloween 4: The Return of Michael Myers'), ('roles', 'cast member')]
# [('workerName', 'Scout Taylor-Compton'), ('workedIn', 'Halloween ,Halloween II'), ('roles', 'cast member ,cast member')]
# [('workerName', 'Sean Hood'), ('workedIn', 'Halloween: Resurrection'), ('roles', 'screenwriter')]
# [('workerName', 'Sean Patrick Thomas'), ('workedIn', 'Halloween: Resurrection'), ('roles', 'cast member')]
# [('workerName', 'Sheri Moon Zombie'), ('workedIn', 'Halloween ,Halloween II'), ('roles', 'cast member ,cast member')]
# [('workerName', 'Sid Haig'), ('workedIn', 'Halloween'), ('roles', 'cast member')]
# [('workerName', 'Silas Weir Mitchell'), ('workedIn', 'Halloween II'), ('roles', 'cast member')]
# [('workerName', 'Skyler Gisondo'), ('workedIn', 'Halloween'), ('roles', 'cast member')]
# [('workerName', 'Stacey Nelkin'), ('workedIn', 'Halloween III: Season of the Witch'), ('roles', 'cast member')]
# [('workerName', 'Steve Miner'), ('workedIn', 'Halloween H20: 20 Years Later'), ('roles', 'cast member ,director')]
# [('workerName', 'Steven Anderson'), ('workedIn', 'Halloween 5: The Revenge of Michael Myers'), ('roles', 'cast member')]
# [('workerName', 'Sybil Danning'), ('workedIn', 'Halloween'), ('roles', 'cast member')]
# [('workerName', 'Sylvia Jefferies'), ('workedIn', 'Halloween II'), ('roles', 'cast member')]
# [('workerName', 'Tamara Glynn'), ('workedIn', 'Halloween 5: The Revenge of Michael Myers'), ('roles', 'cast member')]
# [('workerName', 'Tawny Moyer'), ('workedIn', 'Halloween II'), ('roles', 'cast member')]
# [('workerName', 'Thomas Ian Nicholas'), ('workedIn', 'Halloween: Resurrection'), ('roles', 'cast member')]
# [('workerName', 'Tom Atkins'), ('workedIn', 'Halloween III: Season of the Witch'), ('roles', 'cast member')]
# [('workerName', 'Tom Kane'), ('workedIn', 'Halloween H20: 20 Years Later'), ('roles', 'cast member')]
# [('workerName', 'Tom Towles'), ('workedIn', 'Halloween'), ('roles', 'cast member')]
# [('workerName', 'Tommy Lee Wallace'), ('workedIn', 'Halloween III: Season of the Witch'), ('roles', 'cast member ,director ,screenwriter')]
# [('workerName', 'Tony Moran'), ('workedIn', 'Halloween ,Halloween II'), ('roles', 'cast member ,cast member')]
# [('workerName', 'Troy Evans'), ('workedIn', 'Halloween 5: The Revenge of Michael Myers'), ('roles', 'cast member')]
# [('workerName', 'Tyler Bates'), ('workedIn', 'Halloween ,Halloween II'), ('roles', 'composer ,composer')]
# [('workerName', 'Tyler Mane'), ('workedIn', 'Halloween ,Halloween II'), ('roles', 'cast member ,cast member')]
# [('workerName', 'Tyra Banks'), ('workedIn', 'Halloween: Resurrection'), ('roles', 'cast member')]
# [('workerName', 'Udo Kier'), ('workedIn', 'Halloween'), ('roles', 'cast member')]
# [('workerName', 'Wendy Kaplan'), ('workedIn', 'Halloween 5: The Revenge of Michael Myers'), ('roles', 'cast member')]
# [('workerName', 'William Forsythe'), ('workedIn', 'Halloween'), ('roles', 'cast member ,cast member')]
# 170

# %%
# Return the participations count of worker in Halloween franchises
queryString = """
SELECT DISTINCT ?workerName (COUNT(?propertyName) AS ?participations)
WHERE { 


    # ?film wdt:P179 wd:Q1364022.
    wd:Q1364022 <http://schema.org/name> ?franchiseName.
    
    # ?film ?property ?worker.
    # ?worker <http://schema.org/name> ?workerName.
    
    # ?property <http://schema.org/name> ?propertyName.
    FILTER(?property = wdt:P161 || ?property = wdt:P57 || ?property = wdt:P344 || ?property = wdt:P175 
    || ?property = wdt:P162 || ?property = wdt:2554 || ?property = wdt:P58 || ?property = wdt:P86 || ?property = wdt:P1431)

} 
ORDER BY DESC (?participations)

"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('workerName', 'John Carpenter'), ('participations', '13')]
# [('workerName', 'Moustapha Akkad'), ('participations', '7')]
# [('workerName', 'Debra Hill'), ('participations', '6')]
# [('workerName', 'Rob Zombie'), ('participations', '6')]
# [('workerName', 'Jamie Lee Curtis'), ('participations', '5')]
# [('workerName', 'Donald Pleasence'), ('participations', '5')]
# [('workerName', 'Alan Howarth'), ('participations', '4')]
# [('workerName', 'Danielle Harris'), ('participations', '4')]
# [('workerName', 'Paul Freeman'), ('participations', '4')]
# [('workerName', 'Tommy Lee Wallace'), ('participations', '3')]
# [('workerName', 'Nancy Stephens'), ('participations', '3')]
# [('workerName', 'Dean Cundey'), ('participations', '3')]
# [('workerName', 'Rick Rosenthal'), ('participations', '3')]
# [('workerName', 'Nancy Kyes'), ('participations', '3')]
# [('workerName', 'Tony Moran'), ('participations', '2')]
# [('workerName', 'William Forsythe'), ('participations', '2')]
# [('workerName', 'Malcolm McDowell'), ('participations', '2')]
# [('workerName', 'Sheri Moon Zombie'), ('participations', '2')]
# [('workerName', 'Scout Taylor-Compton'), ('participations', '2')]
# [('workerName', 'George P. Wilbur'), ('participations', '2')]
# [('workerName', 'Dominique Othenin-Girard'), ('participations', '2')]
# [('workerName', 'Brad Dourif'), ('participations', '2')]
# [('workerName', 'Ellie Cornell'), ('participations', '2')]
# [('workerName', 'Tyler Bates'), ('participations', '2')]
# [('workerName', 'Tyler Mane'), ('participations', '2')]
# [('workerName', 'Beau Starr'), ('participations', '2')]
# [('workerName', 'Charles Cyphers'), ('participations', '2')]
# [('workerName', 'Kyle Richards'), ('participations', '2')]
# [('workerName', 'Steve Miner'), ('participations', '2')]
# [('workerName', 'Daniel Roebuck'), ('participations', '2')]
# [('workerName', 'Jeff Daniel Phillips'), ('participations', '2')]
# [('workerName', 'Dick Warlock'), ('participations', '2')]
# [('workerName', 'Skyler Gisondo'), ('participations', '1')]
# [('workerName', 'Arthur Malet'), ('participations', '1')]
# [('workerName', 'Ford Rainey'), ('participations', '1')]
# [('workerName', 'Richard Brake'), ('participations', '1')]
# [('workerName', 'Natassia Malthe'), ('participations', '1')]
# [('workerName', 'Mark Boone Junior'), ('participations', '1')]
# [('workerName', 'Nick Castle'), ('participations', '1')]
# [('workerName', "Dan O'Herlihy"), ('participations', '1')]
# [('workerName', "Jodi Lyn O'Keefe"), ('participations', '1')]
# [('workerName', 'Lew Temple'), ('participations', '1')]
# [('workerName', 'Gabriel Cattand'), ('participations', '1')]
# [('workerName', '"Weird Al" Yankovic'), ('participations', '1')]
# [('workerName', 'Tom Atkins'), ('participations', '1')]
# [('workerName', 'Pat Skipper'), ('participations', '1')]
# [('workerName', 'Kyle Labine'), ('participations', '1')]
# [('workerName', 'Daisy McCrackin'), ('participations', '1')]
# [('workerName', 'Mark Christopher Lawrence'), ('participations', '1')]
# [('workerName', 'Micky Dolenz'), ('participations', '1')]
# [('workerName', 'Sybil Danning'), ('participations', '1')]
# [('workerName', 'Octavia Spencer'), ('participations', '1')]
# [('workerName', 'John Cassini'), ('participations', '1')]
# [('workerName', 'Gregory Nicotero'), ('participations', '1')]
# [('workerName', 'Mary Birdsong'), ('participations', '1')]
# [('workerName', 'Howard Hesseman'), ('participations', '1')]
# [('workerName', 'Daeg Faerch'), ('participations', '1')]
# [('workerName', 'Rachel Galvin'), ('participations', '1')]
# [('workerName', 'Chase Wright Vanek'), ('participations', '1')]
# [('workerName', 'Tamara Glynn'), ('participations', '1')]
# [('workerName', 'David Geddes'), ('participations', '1')]
# [('workerName', 'Billy Dickson'), ('participations', '1')]
# [('workerName', 'Peter Lyons Collister'), ('participations', '1')]
# [('workerName', 'Danny Lux'), ('participations', '1')]
# [('workerName', 'Alan B. McElroy'), ('participations', '1')]
# [('workerName', 'John Ottman'), ('participations', '1')]
# [('workerName', 'Danny Trejo'), ('participations', '1')]
# [('workerName', 'Paddi Edwards'), ('participations', '1')]
# [('workerName', 'Dee Wallace'), ('participations', '1')]
# [('workerName', 'Paul Rudd'), ('participations', '1')]
# [('workerName', 'Daryl Sabara'), ('participations', '1')]
# [('workerName', 'LL Cool J'), ('participations', '1')]
# [('workerName', 'Nick Mennell'), ('participations', '1')]
# [('workerName', 'Thomas Ian Nicholas'), ('participations', '1')]
# [('workerName', 'Pamela Susan Shoop'), ('participations', '1')]
# [('workerName', 'Adam Weisman'), ('participations', '1')]
# [('workerName', 'Ken Foree'), ('participations', '1')]
# [('workerName', 'Beau Billingslea'), ('participations', '1')]
# [('workerName', 'John Michael Graham'), ('participations', '1')]
# [('workerName', 'Irwin Yablans'), ('participations', '1')]
# [('workerName', 'Don Shanks'), ('participations', '1')]
# [('workerName', 'Roland Ménard'), ('participations', '1')]
# [('workerName', 'Bill Moseley'), ('participations', '1')]
# [('workerName', 'Carmen Filpi'), ('participations', '1')]
# [('workerName', 'Sasha Jenson'), ('participations', '1')]
# [('workerName', 'Mitchell Ryan'), ('participations', '1')]
# [('workerName', 'Dayton Callie'), ('participations', '1')]
# [('workerName', 'Betsy Rue'), ('participations', '1')]
# [('workerName', 'Chris Durand'), ('participations', '1')]
# [('workerName', 'Daryn Okada'), ('participations', '1')]
# [('workerName', 'John MacBride'), ('participations', '1')]
# [('workerName', 'Josh Hartnett'), ('participations', '1')]
# [('workerName', 'Dana Carvey'), ('participations', '1')]
# [('workerName', 'Tom Towles'), ('participations', '1')]
# [('workerName', 'Tyra Banks'), ('participations', '1')]
# [('workerName', 'Lance Guest'), ('participations', '1')]
# [('workerName', 'Billy Warlock'), ('participations', '1')]
# [('workerName', 'Steven Anderson'), ('participations', '1')]
# [('workerName', 'Joshua John Miller'), ('participations', '1')]
# [('workerName', 'Max Van Ville'), ('participations', '1')]
# [('workerName', 'Phil Parmet'), ('participations', '1')]
# [('workerName', 'Ryan Merriman'), ('participations', '1')]
# [('workerName', 'Margot Kidder'), ('participations', '1')]
# [('workerName', 'Troy Evans'), ('participations', '1')]
# [('workerName', 'Branden Williams'), ('participations', '1')]
# [('workerName', 'Richard Lynch'), ('participations', '1')]
# [('workerName', 'Brent Chapman'), ('participations', '1')]
# [('workerName', 'Anne-Marie Martin'), ('participations', '1')]
# [('workerName', 'Kristina Klebe'), ('participations', '1')]
# [('workerName', 'Ana Alicia'), ('participations', '1')]
# [('workerName', "Mariah O'Brien"), ('participations', '1')]
# [('workerName', 'Busta Rhymes'), ('participations', '1')]
# [('workerName', 'Kim Darby'), ('participations', '1')]
# [('workerName', 'Bill Fagerbakke'), ('participations', '1')]
# [('workerName', 'Sid Haig'), ('participations', '1')]
# [('workerName', 'Matthew Walker'), ('participations', '1')]
# [('workerName', 'Brea Grant'), ('participations', '1')]
# [('workerName', 'Leo Rossi'), ('participations', '1')]
# [('workerName', 'Lorena Gale'), ('participations', '1')]
# [('workerName', 'Leslie Easterbrook'), ('participations', '1')]
# [('workerName', 'Robert Curtis Brown'), ('participations', '1')]
# [('workerName', 'Ralph Strait'), ('participations', '1')]
# [('workerName', 'Wendy Kaplan'), ('participations', '1')]
# [('workerName', 'Bob Weinstein'), ('participations', '1')]
# [('workerName', 'Luke Kirby'), ('participations', '1')]
# [('workerName', 'Brad Loree'), ('participations', '1')]
# [('workerName', 'Michelle Williams'), ('participations', '1')]
# [('workerName', 'Richard Riehle'), ('participations', '1')]
# [('workerName', 'Matt Winston'), ('participations', '1')]
# [('workerName', 'Udo Kier'), ('participations', '1')]
# [('workerName', 'Bianca Kajlich'), ('participations', '1')]
# [('workerName', 'Adam Arkin'), ('participations', '1')]
# [('workerName', 'Maidie Norman'), ('participations', '1')]
# [('workerName', 'Caroline Williams'), ('participations', '1')]
# [('workerName', 'Tawny Moyer'), ('participations', '1')]
# [('workerName', 'Ryan McDonald'), ('participations', '1')]
# [('workerName', 'Sylvia Jefferies'), ('participations', '1')]
# [('workerName', 'Michael Currie'), ('participations', '1')]
# [('workerName', 'Robert Draper'), ('participations', '1')]
# [('workerName', 'Brandon Trost'), ('participations', '1')]
# [('workerName', 'Daniel Farrands'), ('participations', '1')]
# [('workerName', 'Joe Chappelle'), ('participations', '1')]
# [('workerName', 'Janet Leigh'), ('participations', '1')]
# [('workerName', 'Greg Travis'), ('participations', '1')]
# [('workerName', 'Jonathan Prince'), ('participations', '1')]
# [('workerName', 'Stacey Nelkin'), ('participations', '1')]
# [('workerName', 'Tom Kane'), ('participations', '1')]
# [('workerName', 'Michael Pataki'), ('participations', '1')]
# [('workerName', 'Marianne Hagan'), ('participations', '1')]
# [('workerName', 'Dan Joffre'), ('participations', '1')]
# [('workerName', 'Adam Hann-Byrd'), ('participations', '1')]
# [('workerName', 'Nicky Whelan'), ('participations', '1')]
# [('workerName', 'Sean Hood'), ('participations', '1')]
# [('workerName', 'Sean Patrick Thomas'), ('participations', '1')]
# [('workerName', 'Joseph Gordon-Levitt'), ('participations', '1')]
# [('workerName', 'P. J. Soles'), ('participations', '1')]
# [('workerName', 'Billy Kay'), ('participations', '1')]
# [('workerName', 'Dwight H. Little'), ('participations', '1')]
# [('workerName', 'Matt Greenberg'), ('participations', '1')]
# [('workerName', 'Clint Howard'), ('participations', '1')]
# [('workerName', 'LisaGay Hamilton'), ('participations', '1')]
# [('workerName', 'Chris Hardwick'), ('participations', '1')]
# [('workerName', 'Hanna R. Hall'), ('participations', '1')]
# [('workerName', 'Angela Trimbur'), ('participations', '1')]
# [('workerName', 'Katee Sackhoff'), ('participations', '1')]
# [('workerName', 'Silas Weir Mitchell'), ('participations', '1')]
# [('workerName', 'Duane Whitaker'), ('participations', '1')]
# [('workerName', 'Kathleen Kinmont'), ('participations', '1')]
# [('workerName', 'Cliff Emmich'), ('participations', '1')]
# [('workerName', 'Matt Bush'), ('participations', '1')]
# 170

# %%
# Who is most involved in a franchise (who did something in the movies, e.g., writer, director, producer)?
queryString = """
SELECT ?workerName ?franchiseName ?participations
WHERE {

    {
        SELECT ?workerName ?franchiseName (COUNT(?propertyName) AS ?participations)
        WHERE { 

            # ?film wdt:P179 wd:Q1364022.
            wd:Q1364022 <http://schema.org/name> ?franchiseName.

            # ?film ?property ?worker.
            # ?worker <http://schema.org/name> ?workerName.

            # ?property <http://schema.org/name> ?propertyName.
            FILTER(?property = wdt:P161 || ?property = wdt:P57 || ?property = wdt:P344 || ?property = wdt:P175 
            || ?property = wdt:P162 || ?property = wdt:2554 || ?property = wdt:P58 || ?property = wdt:P86 || ?property = wdt:P1431)

        } 
        ORDER BY DESC (?participations)
        LIMIT 1
    }
    UNION
     {
        SELECT ?workerName ?franchiseName (COUNT(?propertyName) AS ?participations)
        WHERE { 

            # ?film wdt:P179 wd:Q1138878.
            wd:Q1138878 <http://schema.org/name> ?franchiseName.

            # ?film ?property ?worker.
            # ?worker <http://schema.org/name> ?workerName.

            # ?property <http://schema.org/name> ?propertyName.
            FILTER(?property = wdt:P161 || ?property = wdt:P57 || ?property = wdt:P344 || ?property = wdt:P175 
            || ?property = wdt:P162 || ?property = wdt:2554 || ?property = wdt:P58 || ?property = wdt:P86 || ?property = wdt:P1431)

        } 
        ORDER BY DESC (?participations)
        LIMIT 1
    }

}



"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('workerName', 'John Carpenter'), ('franchiseName', 'Halloween'), ('participations', '13')]
# [('workerName', 'Harry Manfredini'), ('franchiseName', 'Friday the 13th'), ('participations', '15')]
# 2

# %% [markdown]
# ### Piont 5 Finish
# DESCRIPTION: I started by considering only Halloween franchise. I consider any person involved in the series using the following properties: “cast member” wdt:P161, “director”  wdt:P57, “dir. of ph.” wdt:P344, “performer” wdt:P175, “producer” wdt:P162, “production designer” wdt:2554, “screenwriter” wdt:P58, “composer” wdt:P86, “executive producer” wdt:P1431, and I count their roles.
# At the end I returned the most involved person for each film series.
#
#
# RESULT: The result shows that John Carpenter was the most active person for Halloween series with 13 participations, while Harry Manfredini was the most involved for Friday the 13th with 15 participations.

# %% [markdown]
# ### Task 6 Start

# %%
# Return all outgoing properies of Halloween franchise
queryString = """
SELECT DISTINCT ?property ?propertyName
WHERE { 

    wd:Q1364022 ?property ?object.
    # ?property <http://schema.org/name> ?propertyName.
} 
ORDER BY ?propertyName
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('property', 'http://www.wikidata.org/prop/direct/P2530'), ('propertyName', 'Box Office Mojo franchise ID (former scheme)')]
# [('property', 'http://www.wikidata.org/prop/direct/P373'), ('propertyName', 'Commons category')]
# [('property', 'http://www.wikidata.org/prop/direct/P646'), ('propertyName', 'Freebase ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7818'), ('propertyName', 'French Vikidia ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1258'), ('propertyName', 'Rotten Tomatoes ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P495'), ('propertyName', 'country of origin')]
# [('property', 'http://www.wikidata.org/prop/direct/P1889'), ('propertyName', 'different from')]
# [('property', 'http://www.wikidata.org/prop/direct/P136'), ('propertyName', 'genre')]
# [('property', 'http://www.wikidata.org/prop/direct/P527'), ('propertyName', 'has part')]
# [('property', 'http://www.wikidata.org/prop/direct/P31'), ('propertyName', 'instance of')]
# [('property', 'http://www.wikidata.org/prop/direct/P364'), ('propertyName', 'original language of film or TV show')]
# [('property', 'http://www.wikidata.org/prop/direct/P9215'), ('propertyName', 'set during recurring event')]
# [('property', 'http://www.wikidata.org/prop/direct/P1476'), ('propertyName', 'title')]
# [('property', 'http://www.wikidata.org/prop/direct/P910'), ('propertyName', "topic's main category")]
# [('property', 'http://www.wikidata.org/prop/direct/P1424'), ('propertyName', "topic's main template")]
# 15

# %%
# Return all ingoing properies of Halloween franchise
queryString = """
SELECT DISTINCT ?property ?propertyName
WHERE { 

    # ?object ?property wd:Q1364022.
    # ?property <http://schema.org/name> ?propertyName.
} 
ORDER BY ?propertyName
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('property', 'http://www.wikidata.org/prop/direct/P301'), ('propertyName', "category's main topic")]
# [('property', 'http://www.wikidata.org/prop/direct/P1889'), ('propertyName', 'different from')]
# [('property', 'http://www.wikidata.org/prop/direct/P8345'), ('propertyName', 'media franchise')]
# [('property', 'http://www.wikidata.org/prop/direct/P179'), ('propertyName', 'part of the series')]
# [('property', 'http://www.wikidata.org/prop/direct/P1441'), ('propertyName', 'present in work')]
# [('property', 'http://www.wikidata.org/prop/direct/P1423'), ('propertyName', 'template has topic')]
# 6

# %%
# Return the assesment of the Halloween film
queryString = """
SELECT DISTINCT ?assessment ?assessmentName
WHERE { 

    wd:Q221103 wdt:P5021 ?assessment.
    # ?assessment <http://schema.org/name> ?assessmentName.
} 
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('assessment', 'http://www.wikidata.org/entity/Q4165246'), ('assessmentName', 'Bechdel test')]
# [('assessment', 'http://www.wikidata.org/entity/Q85783379'), ('assessmentName', 'Mako Mori test')]
# 2

# %%
# Return the received awards of the Halloween film
queryString = """
SELECT DISTINCT ?award ?awardName
WHERE { 

    wd:Q221103 wdt:P166 ?award.
    # ?award <http://schema.org/name> ?awardName.
} 
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('award', 'http://www.wikidata.org/entity/Q823422'), ('awardName', 'National Film Registry')]
# 1

# %%
# Return the assesment of the Friday the 13th film
queryString = """
SELECT DISTINCT ?assesment ?assesmentName
WHERE { 

    wd:Q1243029 wdt:P5021 ?assesment.
    # ?assesment <http://schema.org/name> ?assesmentName.
} 
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('assesment', 'http://www.wikidata.org/entity/Q4165246'), ('assesmentName', 'Bechdel test')]
# 1

# %%
# Return the received awards of the Friday the 13th film
queryString = """
SELECT DISTINCT ?award ?awardName
WHERE { 

    wd:Q1243029 wdt:P166 ?award.
    # ?award <http://schema.org/name> ?awardName.
} 
"""

print("Results")
run_query(queryString)
# Out:
# Results
# Empty
# 0

# %%
# Get all the awards for all Halloween franchise films
queryString = """
SELECT DISTINCT ?film ?filmTitle (GROUP_CONCAT(?awardName; separator = " ,") AS ?awards)
WHERE { 

    # ?film wdt:P179 wd:Q1364022.
    # ?film wdt:P1476 ?filmTitle.
    
    # ?film wdt:P166 ?award.
    # ?award <http://schema.org/name> ?awardName.
} 
ORDER BY (?filmTitle)
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('film', 'http://www.wikidata.org/entity/Q221103'), ('filmTitle', 'Halloween'), ('awards', 'National Film Registry')]
# 1

# %%
# Get all the awards for all Friday the 13th franchise films
queryString = """
SELECT DISTINCT ?film ?filmTitle (GROUP_CONCAT(?awardName; separator = " ,") AS ?awards)
WHERE { 

    # ?film wdt:P179 wd:Q1138878.
    # ?film wdt:P1476 ?filmTitle.
    
    # ?film wdt:P166 ?award.
    # ?award <http://schema.org/name> ?awardName.
} 
ORDER BY (?filmTitle)
"""

print("Results")
run_query(queryString)
# Out:
# Results
# Empty
# 0

# %%
# Investigate which franchise is highly regarded by the critics overall
# Not sure how to effectively evaluate the critics overall of a film
queryString = """
SELECT DISTINCT ?franchiseName (GROUP_CONCAT(?awardName; separator = " ,") AS ?awards)
WHERE { 

    {
        # ?film wdt:P179 wd:Q1364022.
        wd:Q1364022 <http://schema.org/name> ?franchiseName.

        # ?film wdt:P166 ?award.
        # ?award <http://schema.org/name> ?awardName.
    }
    UNION
    {
        # ?film wdt:P179 wd:Q1138878.
        wd:Q1138878 <http://schema.org/name> ?franchiseName.

        # ?film wdt:P166 ?award.
        # ?award <http://schema.org/name> ?awardName.
    }
    
} 
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('franchiseName', 'Halloween'), ('awards', 'National Film Registry')]
# 1

# %% [markdown]
# ### Point 6 Finish
# DESCRIPTION: Again I started by checking all the ingoing and outgoing properties of “Halloween franchise” wd:Q1364022, without finding anything interesting. Then I searched for some relations with Halloween film computed in previous queries and I tried “assessment” wdt:P5021 relation, without any useful results.
# Then I looked for property wdt:P166 “award received” of the Halloween film.
# I performed the same reason as above for Friday the 13th film but obtaining the same conclusion.
# Then I returned all awards for all the films in a franchise to tell how many awards a franchise has won.
# I couldn’t find any other useful relation to evaluate the overall critics so at the end I decided to keep the number of won awards by the franchise.
#
# RESULT: The result shows that only Halloween franchise won an award while Friday the 13th franchise has not.

# %% [markdown]
# ### Task 7 Start

# %%
# Return the cost of Halloween of film
queryString = """
SELECT DISTINCT ?cost
WHERE { 

    wd:Q221103 wdt:P2130 ?cost.
    
} 
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('cost', '325000')]
# 1

# %%
# Return the cost of Halloween franchise films
queryString = """
SELECT ?filmTitle ?cost
WHERE { 

    # ?film wdt:P179 wd:Q1364022.
    wd:Q1364022 <http://schema.org/name> ?franchiseName.
    # ?film wdt:P1476 ?filmTitle.
    
    # ?film wdt:P2130 ?cost
    
    
} 
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('filmTitle', 'Halloween'), ('cost', '325000')]
# 1

# %%
# Return the properties of films of Halloween franchise
queryString = """
SELECT DISTINCT ?property ?propertyName
WHERE { 

    # ?film wdt:P179 wd:Q1364022.

    # ?film ?property ?object.
    # ?property <http://schema.org/name> ?propertyName.
    
    
} 
ORDER BY ?propertyName
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('property', 'http://www.wikidata.org/prop/direct/P3593'), ('propertyName', 'AFI Catalog of Feature Films ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1562'), ('propertyName', 'AllMovie title ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2465'), ('propertyName', 'Allcinema film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1265'), ('propertyName', 'AlloCiné film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P9586'), ('propertyName', 'Apple TV movie ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4632'), ('propertyName', 'Bechdel Test Movie List ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1237'), ('propertyName', 'Box Office Mojo film ID (former scheme)')]
# [('property', 'http://www.wikidata.org/prop/direct/P2758'), ('propertyName', 'CNC film rating (France)')]
# [('property', 'http://www.wikidata.org/prop/direct/P4665'), ('propertyName', 'CineMagia title ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3933'), ('propertyName', 'Cinema.de ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3077'), ('propertyName', 'Cineplex Germany film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3203'), ('propertyName', 'Ciné-Ressources film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4276'), ('propertyName', 'Cinémathèque québécoise work identifier')]
# [('property', 'http://www.wikidata.org/prop/direct/P5905'), ('propertyName', 'Comic Vine ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1804'), ('propertyName', 'DNF film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4277'), ('propertyName', 'Daum movie ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3844'), ('propertyName', 'Deutsche Synchronkartei film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4529'), ('propertyName', 'Douban film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3141'), ('propertyName', 'EDb film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2704'), ('propertyName', 'EIDR content ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2346'), ('propertyName', 'Elonet movie ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1417'), ('propertyName', 'Encyclopædia Britannica Online ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1981'), ('propertyName', 'FSK film rating')]
# [('property', 'http://www.wikidata.org/prop/direct/P7970'), ('propertyName', 'FandangoNow ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6262'), ('propertyName', 'Fandom article ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P480'), ('propertyName', 'FilmAffinity ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7975'), ('propertyName', 'Filmfront film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2747'), ('propertyName', 'Filmiroda rating')]
# [('property', 'http://www.wikidata.org/prop/direct/P3995'), ('propertyName', 'Filmweb.pl ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5032'), ('propertyName', 'Filmweb.pl film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P646'), ('propertyName', 'Freebase ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P227'), ('propertyName', 'GND ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6562'), ('propertyName', 'Google Play Movies & TV ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5680'), ('propertyName', 'Hoopla title ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6466'), ('propertyName', 'Hulu movie ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P345'), ('propertyName', 'IMDb ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3212'), ('propertyName', 'ISAN')]
# [('property', 'http://www.wikidata.org/prop/direct/P5099'), ('propertyName', 'Il mondo dei doppiatori ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2508'), ('propertyName', 'KINENOTE film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2603'), ('propertyName', 'Kinopoisk film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4282'), ('propertyName', 'LUMIERE film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6058'), ('propertyName', 'Larousse ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3107'), ('propertyName', 'LdiF ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6127'), ('propertyName', 'Letterboxd film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P244'), ('propertyName', 'Library of Congress authority ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4780'), ('propertyName', 'MYmovies movie ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5970'), ('propertyName', 'Medierådet rating')]
# [('property', 'http://www.wikidata.org/prop/direct/P1712'), ('propertyName', 'Metacritic ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P8033'), ('propertyName', 'Movie Review Query Engine ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2509'), ('propertyName', 'Movie Walker film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1970'), ('propertyName', 'MovieMeter film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5786'), ('propertyName', 'Moviepilot.de film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1874'), ('propertyName', 'Netflix ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3138'), ('propertyName', 'OFDb film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3302'), ('propertyName', 'Open Media Database film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P905'), ('propertyName', 'PORT film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3417'), ('propertyName', 'Quora topic ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1258'), ('propertyName', 'Rotten Tomatoes ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2518'), ('propertyName', 'Scope.dk film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2334'), ('propertyName', 'Swedish Film Database film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2631'), ('propertyName', 'TCM Movie Database film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4947'), ('propertyName', 'TMDb movie ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3804'), ('propertyName', 'TV Guide show ID (former scheme)')]
# [('property', 'http://www.wikidata.org/prop/direct/P2638'), ('propertyName', 'TV.com ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5357'), ('propertyName', 'The Encyclopedia of Science Fiction ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3808'), ('propertyName', 'The Numbers movie ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P214'), ('propertyName', 'VIAF ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7334'), ('propertyName', 'Vudu video ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2061'), ('propertyName', 'aspect ratio')]
# [('property', 'http://www.wikidata.org/prop/direct/P5021'), ('propertyName', 'assessment')]
# [('property', 'http://www.wikidata.org/prop/direct/P166'), ('propertyName', 'award received')]
# [('property', 'http://www.wikidata.org/prop/direct/P2142'), ('propertyName', 'box office')]
# [('property', 'http://www.wikidata.org/prop/direct/P2769'), ('propertyName', 'budget')]
# [('property', 'http://www.wikidata.org/prop/direct/P161'), ('propertyName', 'cast member')]
# [('property', 'http://www.wikidata.org/prop/direct/P674'), ('propertyName', 'characters')]
# [('property', 'http://www.wikidata.org/prop/direct/P3129'), ('propertyName', 'cine.gr film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P462'), ('propertyName', 'color')]
# [('property', 'http://www.wikidata.org/prop/direct/P86'), ('propertyName', 'composer')]
# [('property', 'http://www.wikidata.org/prop/direct/P2130'), ('propertyName', 'cost')]
# [('property', 'http://www.wikidata.org/prop/direct/P495'), ('propertyName', 'country of origin')]
# [('property', 'http://www.wikidata.org/prop/direct/P4969'), ('propertyName', 'derivative work')]
# [('property', 'http://www.wikidata.org/prop/direct/P1889'), ('propertyName', 'different from')]
# [('property', 'http://www.wikidata.org/prop/direct/P57'), ('propertyName', 'director')]
# [('property', 'http://www.wikidata.org/prop/direct/P344'), ('propertyName', 'director of photography')]
# [('property', 'http://www.wikidata.org/prop/direct/P750'), ('propertyName', 'distributed by')]
# [('property', 'http://www.wikidata.org/prop/direct/P437'), ('propertyName', 'distribution format')]
# [('property', 'http://www.wikidata.org/prop/direct/P2047'), ('propertyName', 'duration')]
# [('property', 'http://www.wikidata.org/prop/direct/P3135'), ('propertyName', 'elCinema film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3143'), ('propertyName', 'elFilm film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1431'), ('propertyName', 'executive producer')]
# [('property', 'http://www.wikidata.org/prop/direct/P2755'), ('propertyName', 'exploitation visa number')]
# [('property', 'http://www.wikidata.org/prop/direct/P1040'), ('propertyName', 'film editor')]
# [('property', 'http://www.wikidata.org/prop/direct/P915'), ('propertyName', 'filming location')]
# [('property', 'http://www.wikidata.org/prop/direct/P156'), ('propertyName', 'followed by')]
# [('property', 'http://www.wikidata.org/prop/direct/P155'), ('propertyName', 'follows')]
# [('property', 'http://www.wikidata.org/prop/direct/P136'), ('propertyName', 'genre')]
# [('property', 'http://www.wikidata.org/prop/direct/P1552'), ('propertyName', 'has quality')]
# [('property', 'http://www.wikidata.org/prop/direct/P6398'), ('propertyName', 'iTunes movie ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P18'), ('propertyName', 'image')]
# [('property', 'http://www.wikidata.org/prop/direct/P31'), ('propertyName', 'instance of')]
# [('property', 'http://www.wikidata.org/prop/direct/P921'), ('propertyName', 'main subject')]
# [('property', 'http://www.wikidata.org/prop/direct/P135'), ('propertyName', 'movement')]
# [('property', 'http://www.wikidata.org/prop/direct/P840'), ('propertyName', 'narrative location')]
# [('property', 'http://www.wikidata.org/prop/direct/P856'), ('propertyName', 'official website')]
# [('property', 'http://www.wikidata.org/prop/direct/P3803'), ('propertyName', 'original film format')]
# [('property', 'http://www.wikidata.org/prop/direct/P364'), ('propertyName', 'original language of film or TV show')]
# [('property', 'http://www.wikidata.org/prop/direct/P179'), ('propertyName', 'part of the series')]
# [('property', 'http://www.wikidata.org/prop/direct/P175'), ('propertyName', 'performer')]
# [('property', 'http://www.wikidata.org/prop/direct/P162'), ('propertyName', 'producer')]
# [('property', 'http://www.wikidata.org/prop/direct/P272'), ('propertyName', 'production company')]
# [('property', 'http://www.wikidata.org/prop/direct/P2554'), ('propertyName', 'production designer')]
# [('property', 'http://www.wikidata.org/prop/direct/P577'), ('propertyName', 'publication date')]
# [('property', 'http://www.wikidata.org/prop/direct/P58'), ('propertyName', 'screenwriter')]
# [('property', 'http://www.wikidata.org/prop/direct/P9215'), ('propertyName', 'set during recurring event')]
# [('property', 'http://www.wikidata.org/prop/direct/P8411'), ('propertyName', 'set in environment')]
# [('property', 'http://www.wikidata.org/prop/direct/P2408'), ('propertyName', 'set in period')]
# [('property', 'http://www.wikidata.org/prop/direct/P1434'), ('propertyName', 'takes place in fictional universe')]
# [('property', 'http://www.wikidata.org/prop/direct/P1476'), ('propertyName', 'title')]
# [('property', 'http://www.wikidata.org/prop/direct/P2529'), ('propertyName', 'ČSFD film ID')]
# 119

# %%
# Return the properties of films of Friday the 13th franchise
queryString = """
SELECT DISTINCT ?property ?propertyName
WHERE { 

    # ?film wdt:P179 wd:Q1138878.

    # ?film ?property ?object.
    # ?property <http://schema.org/name> ?propertyName.
    
    
} 
ORDER BY ?propertyName
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('property', 'http://www.wikidata.org/prop/direct/P3593'), ('propertyName', 'AFI Catalog of Feature Films ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1562'), ('propertyName', 'AllMovie title ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2465'), ('propertyName', 'Allcinema film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1265'), ('propertyName', 'AlloCiné film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P9586'), ('propertyName', 'Apple TV movie ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4632'), ('propertyName', 'Bechdel Test Movie List ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1237'), ('propertyName', 'Box Office Mojo film ID (former scheme)')]
# [('property', 'http://www.wikidata.org/prop/direct/P2758'), ('propertyName', 'CNC film rating (France)')]
# [('property', 'http://www.wikidata.org/prop/direct/P4665'), ('propertyName', 'CineMagia title ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3933'), ('propertyName', 'Cinema.de ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3077'), ('propertyName', 'Cineplex Germany film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3203'), ('propertyName', 'Ciné-Ressources film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4276'), ('propertyName', 'Cinémathèque québécoise work identifier')]
# [('property', 'http://www.wikidata.org/prop/direct/P5905'), ('propertyName', 'Comic Vine ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P373'), ('propertyName', 'Commons category')]
# [('property', 'http://www.wikidata.org/prop/direct/P1804'), ('propertyName', 'DNF film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4277'), ('propertyName', 'Daum movie ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3844'), ('propertyName', 'Deutsche Synchronkartei film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4529'), ('propertyName', 'Douban film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3141'), ('propertyName', 'EDb film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2704'), ('propertyName', 'EIDR content ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2346'), ('propertyName', 'Elonet movie ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1981'), ('propertyName', 'FSK film rating')]
# [('property', 'http://www.wikidata.org/prop/direct/P5693'), ('propertyName', 'Fandango film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7970'), ('propertyName', 'FandangoNow ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6262'), ('propertyName', 'Fandom article ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P480'), ('propertyName', 'FilmAffinity ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7975'), ('propertyName', 'Filmfront film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2747'), ('propertyName', 'Filmiroda rating')]
# [('property', 'http://www.wikidata.org/prop/direct/P5032'), ('propertyName', 'Filmweb.pl film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P646'), ('propertyName', 'Freebase ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6562'), ('propertyName', 'Google Play Movies & TV ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6466'), ('propertyName', 'Hulu movie ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P345'), ('propertyName', 'IMDb ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3212'), ('propertyName', 'ISAN')]
# [('property', 'http://www.wikidata.org/prop/direct/P6827'), ('propertyName', 'Igromania ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5099'), ('propertyName', 'Il mondo dei doppiatori ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3650'), ('propertyName', 'JMK film rating')]
# [('property', 'http://www.wikidata.org/prop/direct/P2508'), ('propertyName', 'KINENOTE film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2684'), ('propertyName', 'Kijkwijzer rating')]
# [('property', 'http://www.wikidata.org/prop/direct/P2603'), ('propertyName', 'Kinopoisk film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4282'), ('propertyName', 'LUMIERE film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3107'), ('propertyName', 'LdiF ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6127'), ('propertyName', 'Letterboxd film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P244'), ('propertyName', 'Library of Congress authority ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4780'), ('propertyName', 'MYmovies movie ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5970'), ('propertyName', 'Medierådet rating')]
# [('property', 'http://www.wikidata.org/prop/direct/P1712'), ('propertyName', 'Metacritic ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7335'), ('propertyName', 'Mixer game ID (former scheme)')]
# [('property', 'http://www.wikidata.org/prop/direct/P8033'), ('propertyName', 'Movie Review Query Engine ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2509'), ('propertyName', 'Movie Walker film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1970'), ('propertyName', 'MovieMeter film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5786'), ('propertyName', 'Moviepilot.de film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4783'), ('propertyName', 'Movieplayer film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5990'), ('propertyName', 'Movies Anywhere ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2363'), ('propertyName', 'NMHH film rating')]
# [('property', 'http://www.wikidata.org/prop/direct/P1874'), ('propertyName', 'Netflix ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3138'), ('propertyName', 'OFDb film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3302'), ('propertyName', 'Open Media Database film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P905'), ('propertyName', 'PORT film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3417'), ('propertyName', 'Quora topic ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6658'), ('propertyName', 'RCQ classification')]
# [('property', 'http://www.wikidata.org/prop/direct/P1258'), ('propertyName', 'Rotten Tomatoes ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2518'), ('propertyName', 'Scope.dk film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2334'), ('propertyName', 'Swedish Film Database film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2631'), ('propertyName', 'TCM Movie Database film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4947'), ('propertyName', 'TMDb movie ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3804'), ('propertyName', 'TV Guide show ID (former scheme)')]
# [('property', 'http://www.wikidata.org/prop/direct/P2638'), ('propertyName', 'TV.com ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3808'), ('propertyName', 'The Numbers movie ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7334'), ('propertyName', 'Vudu video ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2061'), ('propertyName', 'aspect ratio')]
# [('property', 'http://www.wikidata.org/prop/direct/P5021'), ('propertyName', 'assessment')]
# [('property', 'http://www.wikidata.org/prop/direct/P144'), ('propertyName', 'based on')]
# [('property', 'http://www.wikidata.org/prop/direct/P2142'), ('propertyName', 'box office')]
# [('property', 'http://www.wikidata.org/prop/direct/P161'), ('propertyName', 'cast member')]
# [('property', 'http://www.wikidata.org/prop/direct/P674'), ('propertyName', 'characters')]
# [('property', 'http://www.wikidata.org/prop/direct/P3129'), ('propertyName', 'cine.gr film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P462'), ('propertyName', 'color')]
# [('property', 'http://www.wikidata.org/prop/direct/P86'), ('propertyName', 'composer')]
# [('property', 'http://www.wikidata.org/prop/direct/P2130'), ('propertyName', 'cost')]
# [('property', 'http://www.wikidata.org/prop/direct/P2515'), ('propertyName', 'costume designer')]
# [('property', 'http://www.wikidata.org/prop/direct/P495'), ('propertyName', 'country of origin')]
# [('property', 'http://www.wikidata.org/prop/direct/P4969'), ('propertyName', 'derivative work')]
# [('property', 'http://www.wikidata.org/prop/direct/P178'), ('propertyName', 'developer')]
# [('property', 'http://www.wikidata.org/prop/direct/P1889'), ('propertyName', 'different from')]
# [('property', 'http://www.wikidata.org/prop/direct/P57'), ('propertyName', 'director')]
# [('property', 'http://www.wikidata.org/prop/direct/P344'), ('propertyName', 'director of photography')]
# [('property', 'http://www.wikidata.org/prop/direct/P750'), ('propertyName', 'distributed by')]
# [('property', 'http://www.wikidata.org/prop/direct/P437'), ('propertyName', 'distribution format')]
# [('property', 'http://www.wikidata.org/prop/direct/P2047'), ('propertyName', 'duration')]
# [('property', 'http://www.wikidata.org/prop/direct/P3135'), ('propertyName', 'elCinema film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3143'), ('propertyName', 'elFilm film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1431'), ('propertyName', 'executive producer')]
# [('property', 'http://www.wikidata.org/prop/direct/P2755'), ('propertyName', 'exploitation visa number')]
# [('property', 'http://www.wikidata.org/prop/direct/P1040'), ('propertyName', 'film editor')]
# [('property', 'http://www.wikidata.org/prop/direct/P915'), ('propertyName', 'filming location')]
# [('property', 'http://www.wikidata.org/prop/direct/P156'), ('propertyName', 'followed by')]
# [('property', 'http://www.wikidata.org/prop/direct/P155'), ('propertyName', 'follows')]
# [('property', 'http://www.wikidata.org/prop/direct/P404'), ('propertyName', 'game mode')]
# [('property', 'http://www.wikidata.org/prop/direct/P136'), ('propertyName', 'genre')]
# [('property', 'http://www.wikidata.org/prop/direct/P6398'), ('propertyName', 'iTunes movie ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P18'), ('propertyName', 'image')]
# [('property', 'http://www.wikidata.org/prop/direct/P31'), ('propertyName', 'instance of')]
# [('property', 'http://www.wikidata.org/prop/direct/P154'), ('propertyName', 'logo image')]
# [('property', 'http://www.wikidata.org/prop/direct/P840'), ('propertyName', 'narrative location')]
# [('property', 'http://www.wikidata.org/prop/direct/P2438'), ('propertyName', 'narrator')]
# [('property', 'http://www.wikidata.org/prop/direct/P1411'), ('propertyName', 'nominated for')]
# [('property', 'http://www.wikidata.org/prop/direct/P856'), ('propertyName', 'official website')]
# [('property', 'http://www.wikidata.org/prop/direct/P364'), ('propertyName', 'original language of film or TV show')]
# [('property', 'http://www.wikidata.org/prop/direct/P179'), ('propertyName', 'part of the series')]
# [('property', 'http://www.wikidata.org/prop/direct/P175'), ('propertyName', 'performer')]
# [('property', 'http://www.wikidata.org/prop/direct/P400'), ('propertyName', 'platform')]
# [('property', 'http://www.wikidata.org/prop/direct/P162'), ('propertyName', 'producer')]
# [('property', 'http://www.wikidata.org/prop/direct/P272'), ('propertyName', 'production company')]
# [('property', 'http://www.wikidata.org/prop/direct/P2554'), ('propertyName', 'production designer')]
# [('property', 'http://www.wikidata.org/prop/direct/P577'), ('propertyName', 'publication date')]
# [('property', 'http://www.wikidata.org/prop/direct/P58'), ('propertyName', 'screenwriter')]
# [('property', 'http://www.wikidata.org/prop/direct/P8411'), ('propertyName', 'set in environment')]
# [('property', 'http://www.wikidata.org/prop/direct/P1476'), ('propertyName', 'title')]
# [('property', 'http://www.wikidata.org/prop/direct/P8351'), ('propertyName', 'vglist video game ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2529'), ('propertyName', 'ČSFD film ID')]
# 122

# %%
# Return the cost of films of Halloween franchise
queryString = """
SELECT DISTINCT ?film ?filmTitle ?cost
WHERE { 

    # ?film wdt:P179 wd:Q1364022.
    # ?film wdt:P1476 ?filmTitle.

    # ?film ?property ?cost.
    FILTER(?property = wdt:P2130 || ?property = wdt:P2769)
    
    
} 
ORDER BY ?propertyName
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('film', 'http://www.wikidata.org/entity/Q221103'), ('filmTitle', 'Halloween'), ('cost', '325000')]
# [('film', 'http://www.wikidata.org/entity/Q176488'), ('filmTitle', 'Halloween: Resurrection'), ('cost', '15000000')]
# [('film', 'http://www.wikidata.org/entity/Q909063'), ('filmTitle', 'Halloween'), ('cost', '15000000')]
# [('film', 'http://www.wikidata.org/entity/Q203705'), ('filmTitle', 'Halloween III: Season of the Witch'), ('cost', '2500000')]
# [('film', 'http://www.wikidata.org/entity/Q976728'), ('filmTitle', 'Halloween 5: The Revenge of Michael Myers'), ('cost', '3000000')]
# [('film', 'http://www.wikidata.org/entity/Q1138055'), ('filmTitle', 'Halloween: The Curse of Michael Myers'), ('cost', '5000000')]
# 6

# %%
# Return the cost of films of Friday the 13th franchise
queryString = """
SELECT DISTINCT ?film ?filmTitle ?cost
WHERE { 

    # ?film wdt:P179 wd:Q1138878.
    # ?film wdt:P1476 ?filmTitle.

    # ?film ?property ?cost.
    FILTER(?property = wdt:P2130 || ?property = wdt:P2769)
    
    
} 
ORDER BY ?propertyName
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('film', 'http://www.wikidata.org/entity/Q1243009'), ('filmTitle', 'Friday the 13th Part 2'), ('cost', '1250000')]
# [('film', 'http://www.wikidata.org/entity/Q1243013'), ('filmTitle', 'Friday the 13th Part III'), ('cost', '2250000')]
# [('film', 'http://www.wikidata.org/entity/Q1454798'), ('filmTitle', 'Friday the 13th Part VII: The New Blood'), ('cost', '2800000')]
# [('film', 'http://www.wikidata.org/entity/Q1454799'), ('filmTitle', 'Friday the 13th Part VI: Jason Lives'), ('cost', '3000000')]
# [('film', 'http://www.wikidata.org/entity/Q1243019'), ('filmTitle', 'Friday the 13th: The Final Chapter'), ('cost', '2600000')]
# 5

# %%
# Investigate which franchise costed more
queryString = """
SELECT ?franchiseName ?totalCost
WHERE {

    {
        SELECT DISTINCT ?franchiseName (SUM(?cost) AS ?totalCost)
        WHERE { 

            # ?film wdt:P179 wd:Q1364022.
            # ?film wdt:P1476 ?filmTitle.
            wd:Q1364022 <http://schema.org/name> ?franchiseName.

            # ?film ?property ?cost.
            FILTER(?property = wdt:P2130 || ?property = wdt:P2769)
        } 
        GROUP BY ?franchiseName
    }
    UNION
    {
        SELECT DISTINCT ?franchiseName (SUM(?cost) AS ?totalCost)
        WHERE { 

            # ?film wdt:P179 wd:Q1138878.
            # ?film wdt:P1476 ?filmTitle.
            wd:Q1138878 <http://schema.org/name> ?franchiseName.

            # ?film ?property ?cost.
            FILTER(?property = wdt:P2130 || ?property = wdt:P2769)
        } 
        GROUP BY ?franchiseName
    }

}



"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('franchiseName', 'Halloween'), ('totalCost', '40825000')]
# [('franchiseName', 'Friday the 13th'), ('totalCost', '11900000')]
# 2

# %% [markdown]
# ### Point 7 Finish
# DESCRIPTION: I started directly with a relation found above, wdt:P2130 “cost” for the Halloween film. Then I returned the cost of all films in Halloween franchise, but observing that only one film has that relation.
# So I checked again the outgoing properties from Halloween franchise’s films and I discover the relation “budget” wdt:P2769.
# With both relations I can return the information for some of the film in the franchise.
# At the end I was able to find only these two relations, so for every franchise I summed the cost or budget of every film.
#
# RESULT: The result shows that Halloween franchise was the most expensive one. These amounts are not complete, in fact I was able to find some sort of price only for some films.

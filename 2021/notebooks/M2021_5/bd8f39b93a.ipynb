# %% [markdown]
# # General instructions
#
# The goal of the project is to materialize a set of **exploratory workloads** over a real-world, large-scale,  open-domain KG: [WikiData](https://www.wikidata.org/wiki/Wikidata:Main_Page)
#
# An exploratory workload  is composed by a set of queries, where each query is related to the information obtained previously.
#
# An exploratory workload starts with a usually vague, open ended question, and does not assume the person issuing the workload has a clear understanding of the data contained in the target database or its structure.
#
# Remeber that:
#
# 1. All the queries must run in the python notebook
# 2. You can use classes and properties only if you find them via a SPARQL query that must be present in the notebook
# 3. You do not delete useless queries. Keep everything that is synthatically valid
#
# ```
# ?p <http://schema.org/name> ?name .
# ```
#
# is the BGP returning a human-readable name of a property or a class in Wikidata.

# %%
## SETUP used later

from SPARQLWrapper import SPARQLWrapper, JSON


prefixString = """
##-bd8f39b93a-##
PREFIX wd: <http://www.wikidata.org/entity/> 
PREFIX wdt: <http://www.wikidata.org/prop/direct/> 
PREFIX sc: <http://schema.org/>
"""

# select and construct queries
def run_query(queryString):
    to_run = prefixString + "\n" + queryString

    sparql = SPARQLWrapper("http://a256-gc1-02.srv.aau.dk:5820/sparql")
    sparql.setTimeout(300)
    sparql.setReturnFormat(JSON)
    sparql.setQuery(to_run)

    try :
       results = sparql.query()
       json_results = results.convert()
       if len(json_results['results']['bindings'])==0:
          print("Empty")
          return 0
    
       for bindings in json_results['results']['bindings']:
          print( [ (var, value['value'])  for var, value in bindings.items() ] )

       return len(json_results['results']['bindings'])

    except Exception as e :
        print("The operation failed", e)
    
# ASk queries
def run_ask_query(queryString):
    to_run = prefixString + "\n" + queryString

    sparql = SPARQLWrapper("http://a256-gc1-02.srv.aau.dk:5820/sparql")
    sparql.setTimeout(300)
    sparql.setReturnFormat(JSON)
    sparql.setQuery(to_run)

    try :
        return sparql.query().convert()

    except Exception as e :
        print("The operation failed", e)

# %% [markdown]
# # GEO Workflow Series ("archaeological sites")
#
# Consider the following exploratory information need:
#
# > Search for archaeological site in the world, across countries, continents, and in reference to their culture

# %% [markdown]
# ## Useful URIs for the current workflow
#
#
# The following are given:
#
# | IRI           | Description   | Role      |
# | -----------   | -----------   |-----------|
# | `wdt:P1647`   | subproperty   | predicate |
# | `wdt:P31`     | instance of   | predicate |
# | `wdt:P279`    | subclass      | predicate |
# | `wdt:P17`     | country       | predicate |
# | `wd:Q38`      | Italy  | node      |
# | `wd:Q641556`  | Verona Arena  | node      |
# | `wd:Q1747689` | Ancient Rome  | node |
# | `wd:Q46`      | Europe        | node |
# | `wd:Q173527`  | Knossos       | node |
# | `wd:Q839954`  | archaeological site | node |
#
#
# Also consider
#
# ```
# ?p wdt:P17 wd:Q38  .
# ?p wdt:P31 wd:Q839954  .
# ```
#
# is the BGP to retrieve all **archaeological sites in italy**

# %% [markdown]
# ## Workload Goals
#
# 1. Identify the BGP that connect an archaeological site to the country, the continent, and the culture
#
# 2. Identify the BGP to retrieve other types of an archaeological site, e.g., human settlement or theatre
#
# 3. Is there any relevant numerical attribute that describes these sites, e.g., number visitors?
#
# 4. Analyze the number of archaeological sites per type and country
#
#    4.1 Which country has more archaeological sites? Which country has the most  human settlements?
#
#    4.2 Which countries have Ancient Rome sites, which other "archaeological cultures" are described?
#
#    4.3 Which country has the most diverse set of civilizations or cultures across its sites?
#
#    4.4 If you are interested in visiting some sites, which country would you pick? Based on what criteria?

# %%
# start your workflow here

# %% [markdown]
# ## Identify the BGP that connect an archaeological site to the country, the continent, and the culture

# %% [markdown]
# First, I can look for the desired properties for archaeological sites.

# %%
queryString = """
select distinct ?p ?pName where {
    # ?arch wdt:P31 wd:Q839954 ;
          # ?p ?o .
    
    # ?p <http://schema.org/name> ?pName .
    
    filter (regex(?pName, "country|culture", "i"))
}
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P17'), ('pName', 'country')]
# [('p', 'http://www.wikidata.org/prop/direct/P2596'), ('pName', 'culture')]
# [('p', 'http://www.wikidata.org/prop/direct/P3569'), ('pName', 'Cultureel Woordenboek ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8698'), ('pName', "Turkey's Culture Portal ID")]
# [('p', 'http://www.wikidata.org/prop/direct/P205'), ('pName', 'basin country')]
# [('p', 'http://www.wikidata.org/prop/direct/P4702'), ('pName', 'Google Arts & Culture partner ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P495'), ('pName', 'country of origin')]
# [('p', 'http://www.wikidata.org/prop/direct/P8047'), ('pName', 'country of registry')]
# [('p', 'http://www.wikidata.org/prop/direct/P9013'), ('pName', 'Encyclopedia of Saami Culture ID')]
# 9

# %% [markdown]
# So, I can retrieve the country from the property *country (**P17**)* and the culture from property *culture (**P2596**)*.

# %% [markdown]
# For what concern the continent, I must look for the properties in a country, for example Italy.

# %%
queryString = """
select distinct ?p ?pName where {
    wd:Q38 ?p ?o .
    
    # ?p <http://schema.org/name> ?pName .
} order by ?pName
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P8061'), ('pName', 'AGROVOC ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5198'), ('pName', 'ASC Leiden Thesaurus ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6150'), ('pName', 'Academy Awards Database nominee ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8895'), ('pName', 'All the Tropes identifier')]
# [('p', 'http://www.wikidata.org/prop/direct/P7870'), ('pName', 'Analysis & Policy Observatory term ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8785'), ('pName', 'AniDB tag ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P9629'), ('pName', 'Armeniapedia ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6200'), ('pName', 'BBC News topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1617'), ('pName', 'BBC Things ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P9037'), ('pName', 'BHCL UUID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2581'), ('pName', 'BabelNet ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7832'), ('pName', 'Basque Vikidia ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5019'), ('pName', 'Brockhaus Enzyklopädie online ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5180'), ('pName', 'CIVICUS Monitor country entry')]
# [('p', 'http://www.wikidata.org/prop/direct/P9368'), ('pName', 'CNA topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P9123'), ('pName', 'Catalan Vikidia ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5905'), ('pName', 'Comic Vine ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P373'), ('pName', 'Commons category')]
# [('p', 'http://www.wikidata.org/prop/direct/P935'), ('pName', 'Commons gallery')]
# [('p', 'http://www.wikidata.org/prop/direct/P998'), ('pName', 'Curlie ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6849'), ('pName', 'DR topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3509'), ('pName', 'Dagens Nyheter topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1036'), ('pName', 'Dewey Decimal Classification')]
# [('p', 'http://www.wikidata.org/prop/direct/P4589'), ('pName', 'Dreadnought Project page')]
# [('p', 'http://www.wikidata.org/prop/direct/P4672'), ('pName', 'EMLO location ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P9545'), ('pName', 'Encyclopedia of China Online Database ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P4613'), ('pName', 'Encyclopedia of Modern Ukraine ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8935'), ('pName', 'Encyclopedia of the History of Ukraine ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8472'), ('pName', 'Encyclopedie berbere keyword ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1417'), ('pName', 'Encyclopædia Britannica Online ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3219'), ('pName', 'Encyclopædia Universalis ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7829'), ('pName', 'English Vikidia ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5437'), ('pName', 'EuroVoc ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2163'), ('pName', 'FAST ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P901'), ('pName', 'FIPS 10-4 (countries and regions)')]
# [('p', 'http://www.wikidata.org/prop/direct/P6262'), ('pName', 'Fandom article ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P4073'), ('pName', 'Fandom wiki ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P646'), ('pName', 'Freebase ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7818'), ('pName', 'French Vikidia ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P4427'), ('pName', 'GACS ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P227'), ('pName', 'GND ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3067'), ('pName', 'GS1 country code')]
# [('p', 'http://www.wikidata.org/prop/direct/P5400'), ('pName', 'GeoNLP ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1566'), ('pName', 'GeoNames ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1667'), ('pName', 'Getty Thesaurus of Geographic Names ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5247'), ('pName', 'Giant Bomb ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P9100'), ('pName', 'GitHub topic')]
# [('p', 'http://www.wikidata.org/prop/direct/P1842'), ('pName', 'Global Anabaptist Mennonite Encyclopedia Online ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1296'), ('pName', 'Gran Enciclopèdia Catalana ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2924'), ('pName', 'Great Russian Encyclopedia Online ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7295'), ('pName', 'Gregorian calendar start date')]
# [('p', 'http://www.wikidata.org/prop/direct/P8406'), ('pName', 'Grove Art Online ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3106'), ('pName', 'Guardian topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5843'), ('pName', 'Gynopedia ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P902'), ('pName', 'HDS ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7982'), ('pName', 'Hrvatska enciklopedija ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1081'), ('pName', 'Human Development Index')]
# [('p', 'http://www.wikidata.org/prop/direct/P5250'), ('pName', 'IAB code')]
# [('p', 'http://www.wikidata.org/prop/direct/P3422'), ('pName', 'INSEE countries and foreign territories code')]
# [('p', 'http://www.wikidata.org/prop/direct/P984'), ('pName', 'IOC country code')]
# [('p', 'http://www.wikidata.org/prop/direct/P898'), ('pName', 'IPA transcription')]
# [('p', 'http://www.wikidata.org/prop/direct/P3097'), ('pName', 'ISBN identifier group')]
# [('p', 'http://www.wikidata.org/prop/direct/P213'), ('pName', 'ISNI')]
# [('p', 'http://www.wikidata.org/prop/direct/P297'), ('pName', 'ISO 3166-1 alpha-2 code')]
# [('p', 'http://www.wikidata.org/prop/direct/P298'), ('pName', 'ISO 3166-1 alpha-3 code')]
# [('p', 'http://www.wikidata.org/prop/direct/P299'), ('pName', 'ISO 3166-1 numeric code')]
# [('p', 'http://www.wikidata.org/prop/direct/P3024'), ('pName', 'ITU letter code')]
# [('p', 'http://www.wikidata.org/prop/direct/P3743'), ('pName', 'ITU/ISO/IEC object identifier')]
# [('p', 'http://www.wikidata.org/prop/direct/P5063'), ('pName', 'Interlingual Index ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5698'), ('pName', 'Invasive Species Compendium Datasheet ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7822'), ('pName', 'Italian Vikidia ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6413'), ('pName', 'JORFSearch organization ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1438'), ('pName', 'Jewish Encyclopedia ID (Russian)')]
# [('p', 'http://www.wikidata.org/prop/direct/P7960'), ('pName', 'Joconde discovery ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7850'), ('pName', 'Joconde location ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8408'), ('pName', 'KBpedia ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6573'), ('pName', 'Klexikon article ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3612'), ('pName', 'Le Monde diplomatique subject ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7208'), ('pName', 'Liber Liber author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P244'), ('pName', 'Library of Congress authority ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P4801'), ('pName', 'LoC and MARC vocabularies ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7322'), ('pName', 'Marine Regions Geographic IDentifier (MRGID)')]
# [('p', 'http://www.wikidata.org/prop/direct/P486'), ('pName', 'MeSH descriptor ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P982'), ('pName', 'MusicBrainz area ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2004'), ('pName', 'NALT ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3222'), ('pName', 'NE.se ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P691'), ('pName', 'NKCR AUT ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P605'), ('pName', 'NUTS code')]
# [('p', 'http://www.wikidata.org/prop/direct/P8885'), ('pName', 'Namuwiki ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P349'), ('pName', 'National Diet Library ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P949'), ('pName', 'National Library of Israel ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3221'), ('pName', 'New York Times topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2950'), ('pName', 'Nomisma ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1245'), ('pName', 'OmegaWiki Defined Meaning')]
# [('p', 'http://www.wikidata.org/prop/direct/P3479'), ('pName', 'Omni topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P402'), ('pName', 'OpenStreetMap relation ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6592'), ('pName', 'OpenStreetMap zoom level')]
# [('p', 'http://www.wikidata.org/prop/direct/P5002'), ('pName', 'Orthodox Encyclopedia ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5739'), ('pName', 'Pontificia Università della Santa Croce ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1005'), ('pName', 'Portuguese National Library ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8349'), ('pName', 'Proleksis enciklopedija ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P9223'), ('pName', 'Provenio UUID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3417'), ('pName', 'Quora topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8519'), ('pName', 'RKD thesaurus ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8974'), ('pName', 'SAPA ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3987'), ('pName', 'SHARE Catalogue author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3911'), ('pName', 'STW Thesaurus for Economics ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P9757'), ('pName', 'Schoenberg Database of Manuscripts place ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7827'), ('pName', 'Spanish Vikidia ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P9122'), ('pName', 'SportsLogos.net team ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3175'), ('pName', 'Statoids ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P4342'), ('pName', 'Store norske leksikon ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7314'), ('pName', 'TDV İslam Ansiklopedisi ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6839'), ('pName', 'TV Tropes identifier')]
# [('p', 'http://www.wikidata.org/prop/direct/P5456'), ('pName', 'TasteAtlas ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7157'), ('pName', 'The Top Tens ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3365'), ('pName', 'Treccani ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6404'), ('pName', "Treccani's Dizionario di Storia ID")]
# [('p', 'http://www.wikidata.org/prop/direct/P1225'), ('pName', 'U.S. National Archives Identifier')]
# [('p', 'http://www.wikidata.org/prop/direct/P2981'), ('pName', 'UIC alphabetical country code')]
# [('p', 'http://www.wikidata.org/prop/direct/P2982'), ('pName', 'UIC numerical country code')]
# [('p', 'http://www.wikidata.org/prop/direct/P4527'), ('pName', 'UK Parliament thesaurus ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3916'), ('pName', 'UNESCO Thesaurus ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P487'), ('pName', 'Unicode character')]
# [('p', 'http://www.wikidata.org/prop/direct/P2855'), ('pName', 'VAT-rate')]
# [('p', 'http://www.wikidata.org/prop/direct/P214'), ('pName', 'VIAF ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3068'), ('pName', 'WIPO ST.3')]
# [('p', 'http://www.wikidata.org/prop/direct/P6766'), ('pName', "Who's on First ID")]
# [('p', 'http://www.wikidata.org/prop/direct/P5125'), ('pName', 'Wikimedia outline')]
# [('p', 'http://www.wikidata.org/prop/direct/P8814'), ('pName', 'WordNet 3.1 Synset ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7012'), ('pName', 'World Encyclopedia of Puppetry Arts ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7859'), ('pName', 'WorldCat Identities ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6293'), ('pName', 'YSA ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2347'), ('pName', 'YSO ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8309'), ('pName', 'Yle topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3553'), ('pName', 'Zhihu topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2997'), ('pName', 'age of majority')]
# [('p', 'http://www.wikidata.org/prop/direct/P85'), ('pName', 'anthem')]
# [('p', 'http://www.wikidata.org/prop/direct/P5573'), ('pName', 'archINFORM location ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2046'), ('pName', 'area')]
# [('p', 'http://www.wikidata.org/prop/direct/P122'), ('pName', 'basic form of government')]
# [('p', 'http://www.wikidata.org/prop/direct/P36'), ('pName', 'capital')]
# [('p', 'http://www.wikidata.org/prop/direct/P1740'), ('pName', 'category for films shot at this location')]
# [('p', 'http://www.wikidata.org/prop/direct/P7867'), ('pName', 'category for maps')]
# [('p', 'http://www.wikidata.org/prop/direct/P1465'), ('pName', 'category for people who died here')]
# [('p', 'http://www.wikidata.org/prop/direct/P1464'), ('pName', 'category for people born here')]
# [('p', 'http://www.wikidata.org/prop/direct/P1792'), ('pName', 'category of associated people')]
# [('p', 'http://www.wikidata.org/prop/direct/P1791'), ('pName', 'category of people buried here')]
# [('p', 'http://www.wikidata.org/prop/direct/P237'), ('pName', 'coat of arms')]
# [('p', 'http://www.wikidata.org/prop/direct/P94'), ('pName', 'coat of arms image')]
# [('p', 'http://www.wikidata.org/prop/direct/P3271'), ('pName', 'compulsory education (maximum age)')]
# [('p', 'http://www.wikidata.org/prop/direct/P3270'), ('pName', 'compulsory education (minimum age)')]
# [('p', 'http://www.wikidata.org/prop/direct/P150'), ('pName', 'contains administrative territorial entity')]
# [('p', 'http://www.wikidata.org/prop/direct/P30'), ('pName', 'continent')]
# [('p', 'http://www.wikidata.org/prop/direct/P17'), ('pName', 'country')]
# [('p', 'http://www.wikidata.org/prop/direct/P474'), ('pName', 'country calling code')]
# [('p', 'http://www.wikidata.org/prop/direct/P2596'), ('pName', 'culture')]
# [('p', 'http://www.wikidata.org/prop/direct/P38'), ('pName', 'currency')]
# [('p', 'http://www.wikidata.org/prop/direct/P9241'), ('pName', 'demographics of topic')]
# [('p', 'http://www.wikidata.org/prop/direct/P1549'), ('pName', 'demonym')]
# [('p', 'http://www.wikidata.org/prop/direct/P1343'), ('pName', 'described by source')]
# [('p', 'http://www.wikidata.org/prop/direct/P530'), ('pName', 'diplomatic relation')]
# [('p', 'http://www.wikidata.org/prop/direct/P1622'), ('pName', 'driving side')]
# [('p', 'http://www.wikidata.org/prop/direct/P8744'), ('pName', 'economy of topic')]
# [('p', 'http://www.wikidata.org/prop/direct/P8826'), ('pName', 'edition humboldt digital ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2853'), ('pName', 'electrical plug type')]
# [('p', 'http://www.wikidata.org/prop/direct/P2852'), ('pName', 'emergency telephone number')]
# [('p', 'http://www.wikidata.org/prop/direct/P208'), ('pName', 'executive body')]
# [('p', 'http://www.wikidata.org/prop/direct/P163'), ('pName', 'flag')]
# [('p', 'http://www.wikidata.org/prop/direct/P41'), ('pName', 'flag image')]
# [('p', 'http://www.wikidata.org/prop/direct/P155'), ('pName', 'follows')]
# [('p', 'http://www.wikidata.org/prop/direct/P2633'), ('pName', 'geography of topic')]
# [('p', 'http://www.wikidata.org/prop/direct/P3896'), ('pName', 'geoshape')]
# [('p', 'http://www.wikidata.org/prop/direct/P1552'), ('pName', 'has quality')]
# [('p', 'http://www.wikidata.org/prop/direct/P6'), ('pName', 'head of government')]
# [('p', 'http://www.wikidata.org/prop/direct/P35'), ('pName', 'head of state')]
# [('p', 'http://www.wikidata.org/prop/direct/P209'), ('pName', 'highest judicial authority')]
# [('p', 'http://www.wikidata.org/prop/direct/P610'), ('pName', 'highest point')]
# [('p', 'http://www.wikidata.org/prop/direct/P2184'), ('pName', 'history of topic')]
# [('p', 'http://www.wikidata.org/prop/direct/P8217'), ('pName', 'iDAI.gazetteer ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7471'), ('pName', 'iNaturalist place ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P571'), ('pName', 'inception')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('p', 'http://www.wikidata.org/prop/direct/P2936'), ('pName', 'language used')]
# [('p', 'http://www.wikidata.org/prop/direct/P194'), ('pName', 'legislative body')]
# [('p', 'http://www.wikidata.org/prop/direct/P395'), ('pName', 'licence plate code')]
# [('p', 'http://www.wikidata.org/prop/direct/P2250'), ('pName', 'life expectancy')]
# [('p', 'http://www.wikidata.org/prop/direct/P206'), ('pName', 'located in or next to body of water')]
# [('p', 'http://www.wikidata.org/prop/direct/P421'), ('pName', 'located in time zone')]
# [('p', 'http://www.wikidata.org/prop/direct/P706'), ('pName', 'located in/on physical feature')]
# [('p', 'http://www.wikidata.org/prop/direct/P242'), ('pName', 'locator map image')]
# [('p', 'http://www.wikidata.org/prop/direct/P1589'), ('pName', 'lowest point')]
# [('p', 'http://www.wikidata.org/prop/direct/P92'), ('pName', 'main regulatory text')]
# [('p', 'http://www.wikidata.org/prop/direct/P2884'), ('pName', 'mains voltage')]
# [('p', 'http://www.wikidata.org/prop/direct/P6104'), ('pName', 'maintained by WikiProject')]
# [('p', 'http://www.wikidata.org/prop/direct/P2979'), ('pName', 'maritime identification digits')]
# [('p', 'http://www.wikidata.org/prop/direct/P3000'), ('pName', 'marriageable age')]
# [('p', 'http://www.wikidata.org/prop/direct/P3529'), ('pName', 'median income')]
# [('p', 'http://www.wikidata.org/prop/direct/P463'), ('pName', 'member of')]
# [('p', 'http://www.wikidata.org/prop/direct/P7422'), ('pName', 'minimum temperature record')]
# [('p', 'http://www.wikidata.org/prop/direct/P2258'), ('pName', 'mobile country code')]
# [('p', 'http://www.wikidata.org/prop/direct/P1451'), ('pName', 'motto text')]
# [('p', 'http://www.wikidata.org/prop/direct/P1120'), ('pName', 'number of deaths')]
# [('p', 'http://www.wikidata.org/prop/direct/P2573'), ('pName', 'number of out-of-school children')]
# [('p', 'http://www.wikidata.org/prop/direct/P1906'), ('pName', 'office held by head of state')]
# [('p', 'http://www.wikidata.org/prop/direct/P1313'), ('pName', 'office held by head of government')]
# [('p', 'http://www.wikidata.org/prop/direct/P37'), ('pName', 'official language')]
# [('p', 'http://www.wikidata.org/prop/direct/P856'), ('pName', 'official website')]
# [('p', 'http://www.wikidata.org/prop/direct/P5008'), ('pName', 'on focus list of Wikimedia project')]
# [('p', 'http://www.wikidata.org/prop/direct/P8402'), ('pName', 'open data portal')]
# [('p', 'http://www.wikidata.org/prop/direct/P948'), ('pName', 'page banner')]
# [('p', 'http://www.wikidata.org/prop/direct/P361'), ('pName', 'part of')]
# [('p', 'http://www.wikidata.org/prop/direct/P417'), ('pName', 'patron saint')]
# [('p', 'http://www.wikidata.org/prop/direct/P2959'), ('pName', 'permanent duplicated item')]
# [('p', 'http://www.wikidata.org/prop/direct/P1082'), ('pName', 'population')]
# [('p', 'http://www.wikidata.org/prop/direct/P443'), ('pName', 'pronunciation audio')]
# [('p', 'http://www.wikidata.org/prop/direct/P832'), ('pName', 'public holiday')]
# [('p', 'http://www.wikidata.org/prop/direct/P5658'), ('pName', 'railway traffic side')]
# [('p', 'http://www.wikidata.org/prop/direct/P1365'), ('pName', 'replaces')]
# [('p', 'http://www.wikidata.org/prop/direct/P1419'), ('pName', 'shape')]
# [('p', 'http://www.wikidata.org/prop/direct/P47'), ('pName', 'shares border with')]
# [('p', 'http://www.wikidata.org/prop/direct/P3984'), ('pName', 'subreddit')]
# [('p', 'http://www.wikidata.org/prop/direct/P78'), ('pName', 'top-level Internet domain')]
# [('p', 'http://www.wikidata.org/prop/direct/P1151'), ('pName', "topic's main Wikimedia portal")]
# [('p', 'http://www.wikidata.org/prop/direct/P910'), ('pName', "topic's main category")]
# [('p', 'http://www.wikidata.org/prop/direct/P4841'), ('pName', 'total fertility rate')]
# [('p', 'http://www.wikidata.org/prop/direct/P1198'), ('pName', 'unemployment rate')]
# [('p', 'http://www.wikidata.org/prop/direct/P2436'), ('pName', 'voltage')]
# [('p', 'http://www.wikidata.org/prop/direct/P9318'), ('pName', 'Ávvir topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8432'), ('pName', 'Österreichisches Musiklexikon Online ID')]
# 230

# %% [markdown]
# The countries are connected to the continent through the property *continent (**P30**)*. So, the final BGP to get the country, the continent and the culture of an archeological site is:
#
# ```
# ?arch wdt:P17 ?country ;
#       wdt:P2596 ?culture .
# ?country wdt:P30 ?continent .
# ```

# %% [markdown]
# I can try it with Arena di Verona

# %%
queryString = """
select ?archName ?countryName ?continentName ?cultureName where {
    values ?arch { wd:Q641556 } .
    
    # ?arch wdt:P17 ?country ;
          wdt:P2596 ?culture .
    # ?country wdt:P30 ?continent .
    
    # ?arch <http://schema.org/name> ?archName .
    # ?country <http://schema.org/name> ?countryName .
    # ?continent <http://schema.org/name> ?continentName .
    # ?culture <http://schema.org/name> ?cultureName .
}
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('archName', 'Verona Arena'), ('countryName', 'Italy'), ('continentName', 'Europe'), ('cultureName', 'Ancient Rome')]
# 1

# %% [markdown]
# ## 2. Identify the BGP to retrieve other types of an archaeological site, e.g., human settlement or theatre

# %% [markdown]
# To answer this question, I can retrieve the list of instances connected to archeological sites

# %%
queryString = """
select distinct ?type ?typeName where {
    # ?arch wdt:P31 wd:Q839954 ;
          wdt:P31 ?type .
    
    # ?type <http://schema.org/name> ?typeName .
}
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('type', 'http://www.wikidata.org/entity/Q14947481'), ('typeName', 'wierde')]
# [('type', 'http://www.wikidata.org/entity/Q505963'), ('typeName', 'artificial dwelling hill')]
# [('type', 'http://www.wikidata.org/entity/Q14601169'), ('typeName', 'human fortified settlement')]
# [('type', 'http://www.wikidata.org/entity/Q325017'), ('typeName', 'causewayed enclosure')]
# [('type', 'http://www.wikidata.org/entity/Q5069563'), ('typeName', 'chambered long barrow')]
# [('type', 'http://www.wikidata.org/entity/Q30504603'), ('typeName', 'Maya site in Mexico')]
# [('type', 'http://www.wikidata.org/entity/Q6581615'), ('typeName', 'thermae')]
# [('type', 'http://www.wikidata.org/entity/Q95463156'), ('typeName', 'Ancient Roman dam')]
# [('type', 'http://www.wikidata.org/entity/Q1128906'), ('typeName', 'medina quarter')]
# [('type', 'http://www.wikidata.org/entity/Q19979289'), ('typeName', 'birth house')]
# [('type', 'http://www.wikidata.org/entity/Q29702995'), ('typeName', 'chalkotheke')]
# [('type', 'http://www.wikidata.org/entity/Q1193753'), ('typeName', 'stone row')]
# [('type', 'http://www.wikidata.org/entity/Q2006795'), ('typeName', 'abschnittsmotte')]
# [('type', 'http://www.wikidata.org/entity/Q28936794'), ('typeName', 'provincial park in Saskatchewan')]
# [('type', 'http://www.wikidata.org/entity/Q37988355'), ('typeName', 'Tennessee state park')]
# [('type', 'http://www.wikidata.org/entity/Q31028314'), ('typeName', 'partial contour fort')]
# [('type', 'http://www.wikidata.org/entity/Q146924'), ('typeName', 'Roman limes')]
# [('type', 'http://www.wikidata.org/entity/Q173387'), ('typeName', 'grave')]
# [('type', 'http://www.wikidata.org/entity/Q1785071'), ('typeName', 'fort')]
# [('type', 'http://www.wikidata.org/entity/Q2065736'), ('typeName', 'cultural property')]
# [('type', 'http://www.wikidata.org/entity/Q2977'), ('typeName', 'cathedral')]
# [('type', 'http://www.wikidata.org/entity/Q372363'), ('typeName', 'geotope')]
# [('type', 'http://www.wikidata.org/entity/Q3947'), ('typeName', 'house')]
# [('type', 'http://www.wikidata.org/entity/Q44613'), ('typeName', 'monastery')]
# [('type', 'http://www.wikidata.org/entity/Q473972'), ('typeName', 'protected area')]
# [('type', 'http://www.wikidata.org/entity/Q1497375'), ('typeName', 'architectural ensemble')]
# [('type', 'http://www.wikidata.org/entity/Q22022298'), ('typeName', 'rock relief')]
# [('type', 'http://www.wikidata.org/entity/Q152081'), ('typeName', 'concentration camp')]
# [('type', 'http://www.wikidata.org/entity/Q15243209'), ('typeName', 'historic district')]
# [('type', 'http://www.wikidata.org/entity/Q164240'), ('typeName', 'megalith')]
# [('type', 'http://www.wikidata.org/entity/Q17376095'), ('typeName', 'cadastral municipality of Austria')]
# [('type', 'http://www.wikidata.org/entity/Q2887138'), ('typeName', 'civil basilica')]
# [('type', 'http://www.wikidata.org/entity/Q2989470'), ('typeName', 'commune of Mauritania')]
# [('type', 'http://www.wikidata.org/entity/Q4363262'), ('typeName', 'smooth-sided pyramid')]
# [('type', 'http://www.wikidata.org/entity/Q11269813'), ('typeName', 'cave with prehistoric art')]
# [('type', 'http://www.wikidata.org/entity/Q14752696'), ('typeName', 'ancient Roman structure')]
# [('type', 'http://www.wikidata.org/entity/Q15893266'), ('typeName', 'former entity')]
# [('type', 'http://www.wikidata.org/entity/Q1930585'), ('typeName', 'victory column')]
# [('type', 'http://www.wikidata.org/entity/Q2087181'), ('typeName', 'historic house museum')]
# [('type', 'http://www.wikidata.org/entity/Q2232001'), ('typeName', 'show cave')]
# [('type', 'http://www.wikidata.org/entity/Q2434238'), ('typeName', 'heritage')]
# [('type', 'http://www.wikidata.org/entity/Q88205'), ('typeName', 'castrum')]
# [('type', 'http://www.wikidata.org/entity/Q14524493'), ('typeName', 'terrain')]
# [('type', 'http://www.wikidata.org/entity/Q2197893'), ('typeName', 'chine')]
# [('type', 'http://www.wikidata.org/entity/Q2561694'), ('typeName', 'city-kingdom of Cyprus')]
# [('type', 'http://www.wikidata.org/entity/Q29553'), ('typeName', 'sanctuary')]
# [('type', 'http://www.wikidata.org/entity/Q3395377'), ('typeName', 'ancient monument')]
# [('type', 'http://www.wikidata.org/entity/Q628505'), ('typeName', 'labor camp')]
# [('type', 'http://www.wikidata.org/entity/Q1051606'), ('typeName', 'Daibutsu')]
# [('type', 'http://www.wikidata.org/entity/Q17485079'), ('typeName', 'church ruin')]
# [('type', 'http://www.wikidata.org/entity/Q200141'), ('typeName', 'necropolis')]
# [('type', 'http://www.wikidata.org/entity/Q30304302'), ('typeName', 'National Park System unit')]
# [('type', 'http://www.wikidata.org/entity/Q32815'), ('typeName', 'mosque')]
# [('type', 'http://www.wikidata.org/entity/Q782970'), ('typeName', 'Domus')]
# [('type', 'http://www.wikidata.org/entity/Q893775'), ('typeName', 'National Monument of the United States')]
# [('type', 'http://www.wikidata.org/entity/Q217123'), ('typeName', 'oracle')]
# [('type', 'http://www.wikidata.org/entity/Q25297630'), ('typeName', 'international bridge')]
# [('type', 'http://www.wikidata.org/entity/Q3363945'), ('typeName', 'archaeological park')]
# [('type', 'http://www.wikidata.org/entity/Q465960'), ('typeName', 'Jesuit missions among the Guaraní')]
# [('type', 'http://www.wikidata.org/entity/Q744099'), ('typeName', 'hillfort')]
# [('type', 'http://www.wikidata.org/entity/Q131668'), ('typeName', 'acropolis')]
# [('type', 'http://www.wikidata.org/entity/Q1708422'), ('typeName', 'settlement site')]
# [('type', 'http://www.wikidata.org/entity/Q756944'), ('typeName', 'surface mining')]
# [('type', 'http://www.wikidata.org/entity/Q3329412'), ('typeName', 'archaeological museum')]
# [('type', 'http://www.wikidata.org/entity/Q7362268'), ('typeName', 'Roman amphitheatre')]
# [('type', 'http://www.wikidata.org/entity/Q193475'), ('typeName', 'menhir')]
# [('type', 'http://www.wikidata.org/entity/Q842402'), ('typeName', 'Hindu temple')]
# [('type', 'http://www.wikidata.org/entity/Q34023'), ('typeName', 'tumulus')]
# [('type', 'http://www.wikidata.org/entity/Q6304550'), ('typeName', 'anta')]
# [('type', 'http://www.wikidata.org/entity/Q102496'), ('typeName', 'parish')]
# [('type', 'http://www.wikidata.org/entity/Q1057440'), ('typeName', 'Heraion')]
# [('type', 'http://www.wikidata.org/entity/Q5228121'), ('typeName', 'dava')]
# [('type', 'http://www.wikidata.org/entity/Q131596'), ('typeName', 'farm')]
# [('type', 'http://www.wikidata.org/entity/Q13955118'), ('typeName', 'earthwork')]
# [('type', 'http://www.wikidata.org/entity/Q1134686'), ('typeName', 'frazione')]
# [('type', 'http://www.wikidata.org/entity/Q12280'), ('typeName', 'bridge')]
# [('type', 'http://www.wikidata.org/entity/Q143912'), ('typeName', 'triumphal arch')]
# [('type', 'http://www.wikidata.org/entity/Q1549591'), ('typeName', 'big city')]
# [('type', 'http://www.wikidata.org/entity/Q15661340'), ('typeName', 'ancient city')]
# [('type', 'http://www.wikidata.org/entity/Q16560'), ('typeName', 'palace')]
# [('type', 'http://www.wikidata.org/entity/Q16970'), ('typeName', 'church building')]
# [('type', 'http://www.wikidata.org/entity/Q174782'), ('typeName', 'square')]
# [('type', 'http://www.wikidata.org/entity/Q2221906'), ('typeName', 'geographic location')]
# [('type', 'http://www.wikidata.org/entity/Q23413'), ('typeName', 'castle')]
# [('type', 'http://www.wikidata.org/entity/Q23442'), ('typeName', 'island')]
# [('type', 'http://www.wikidata.org/entity/Q3024240'), ('typeName', 'historical country')]
# [('type', 'http://www.wikidata.org/entity/Q3257686'), ('typeName', 'locality')]
# [('type', 'http://www.wikidata.org/entity/Q3957'), ('typeName', 'town')]
# [('type', 'http://www.wikidata.org/entity/Q44539'), ('typeName', 'temple')]
# [('type', 'http://www.wikidata.org/entity/Q46169'), ('typeName', 'national park')]
# [('type', 'http://www.wikidata.org/entity/Q474'), ('typeName', 'aqueduct')]
# [('type', 'http://www.wikidata.org/entity/Q486972'), ('typeName', 'human settlement')]
# [('type', 'http://www.wikidata.org/entity/Q207326'), ('typeName', 'summit')]
# [('type', 'http://www.wikidata.org/entity/Q24354'), ('typeName', 'theatre')]
# [('type', 'http://www.wikidata.org/entity/Q253019'), ('typeName', 'Ortsteil')]
# [('type', 'http://www.wikidata.org/entity/Q34627'), ('typeName', 'synagogue')]
# [('type', 'http://www.wikidata.org/entity/Q3914'), ('typeName', 'school')]
# [('type', 'http://www.wikidata.org/entity/Q484170'), ('typeName', 'commune of France')]
# [('type', 'http://www.wikidata.org/entity/Q657100'), ('typeName', 'colonnade')]
# [('type', 'http://www.wikidata.org/entity/Q1115575'), ('typeName', 'civil parish')]
# [('type', 'http://www.wikidata.org/entity/Q12518'), ('typeName', 'tower')]
# [('type', 'http://www.wikidata.org/entity/Q1370468'), ('typeName', 'reconstruction')]
# [('type', 'http://www.wikidata.org/entity/Q15310171'), ('typeName', 'seaport')]
# [('type', 'http://www.wikidata.org/entity/Q160091'), ('typeName', 'plain')]
# [('type', 'http://www.wikidata.org/entity/Q178743'), ('typeName', 'stele')]
# [('type', 'http://www.wikidata.org/entity/Q211302'), ('typeName', 'glacial lake')]
# [('type', 'http://www.wikidata.org/entity/Q220659'), ('typeName', 'archaeological artifact')]
# [('type', 'http://www.wikidata.org/entity/Q2319498'), ('typeName', 'landmark')]
# [('type', 'http://www.wikidata.org/entity/Q27686'), ('typeName', 'hotel')]
# [('type', 'http://www.wikidata.org/entity/Q350895'), ('typeName', 'abandoned village')]
# [('type', 'http://www.wikidata.org/entity/Q7075'), ('typeName', 'library')]
# [('type', 'http://www.wikidata.org/entity/Q209287'), ('typeName', 'Wonders of the World')]
# [('type', 'http://www.wikidata.org/entity/Q832778'), ('typeName', 'campsite')]
# [('type', 'http://www.wikidata.org/entity/Q96211395'), ('typeName', 'heritage site in Sweden')]
# [('type', 'http://www.wikidata.org/entity/Q1788752'), ('typeName', 'kongsgård')]
# [('type', 'http://www.wikidata.org/entity/Q10521078'), ('typeName', 'megalithic tomb')]
# [('type', 'http://www.wikidata.org/entity/Q1424609'), ('typeName', 'kettle')]
# [('type', 'http://www.wikidata.org/entity/Q1936626'), ('typeName', 'aisleless church')]
# [('type', 'http://www.wikidata.org/entity/Q358316'), ('typeName', 'chamber tomb')]
# [('type', 'http://www.wikidata.org/entity/Q92107'), ('typeName', 'quadrangular castle')]
# [('type', 'http://www.wikidata.org/entity/Q105999'), ('typeName', 'cargo ship')]
# [('type', 'http://www.wikidata.org/entity/Q12783'), ('typeName', 'English garden')]
# [('type', 'http://www.wikidata.org/entity/Q153562'), ('typeName', 'opera house')]
# [('type', 'http://www.wikidata.org/entity/Q15727816'), ('typeName', 'painting series')]
# [('type', 'http://www.wikidata.org/entity/Q16887380'), ('typeName', 'group')]
# [('type', 'http://www.wikidata.org/entity/Q22698'), ('typeName', 'park')]
# [('type', 'http://www.wikidata.org/entity/Q34038'), ('typeName', 'waterfall')]
# [('type', 'http://www.wikidata.org/entity/Q631305'), ('typeName', 'rock formation')]
# [('type', 'http://www.wikidata.org/entity/Q811430'), ('typeName', 'human-made geographic feature')]
# [('type', 'http://www.wikidata.org/entity/Q2919841'), ('typeName', 'protected area of Brazil')]
# [('type', 'http://www.wikidata.org/entity/Q800062'), ('typeName', 'Back Country Byway')]
# [('type', 'http://www.wikidata.org/entity/Q332128'), ('typeName', 'Promontory forts')]
# [('type', 'http://www.wikidata.org/entity/Q102202026'), ('typeName', 'Samian Ware Productioncentre')]
# [('type', 'http://www.wikidata.org/entity/Q11679502'), ('typeName', 'Jewish holy places in Israel')]
# [('type', 'http://www.wikidata.org/entity/Q13516676'), ('typeName', 'cross dyke')]
# ...
# [('type', 'http://www.wikidata.org/entity/Q40364446'), ('typeName', 'historic city')]
# [('type', 'http://www.wikidata.org/entity/Q97466153'), ('typeName', 'memorial arch')]
# [('type', 'http://www.wikidata.org/entity/Q4868864'), ('typeName', 'batey')]
# [('type', 'http://www.wikidata.org/entity/Q17645016'), ('typeName', 'Iron Age settlement')]
# [('type', 'http://www.wikidata.org/entity/Q863906'), ('typeName', 'inland dune')]
# [('type', 'http://www.wikidata.org/entity/Q7257917'), ('typeName', 'Public infrastructure')]
# [('type', 'http://www.wikidata.org/entity/Q1433492'), ('typeName', 'stone ship')]
# [('type', 'http://www.wikidata.org/entity/Q1923257'), ('typeName', 'hall house')]
# [('type', 'http://www.wikidata.org/entity/Q3455524'), ('typeName', 'administrative region')]
# [('type', 'http://www.wikidata.org/entity/Q75520'), ('typeName', 'plateau')]
# [('type', 'http://www.wikidata.org/entity/Q7481320'), ('typeName', 'drainage')]
# [('type', 'http://www.wikidata.org/entity/Q63065035'), ('typeName', 'abandoned')]
# [('type', 'http://www.wikidata.org/entity/Q1724341'), ('typeName', 'kiln')]
# [('type', 'http://www.wikidata.org/entity/Q1141208'), ('typeName', 'cross slab')]
# [('type', 'http://www.wikidata.org/entity/Q29569274'), ('typeName', 'former name')]
# [('type', 'http://www.wikidata.org/entity/Q1571674'), ('typeName', 'fortified church')]
# [('type', 'http://www.wikidata.org/entity/Q2871500'), ('typeName', 'Augusteum')]
# [('type', 'http://www.wikidata.org/entity/Q695860'), ('typeName', 'recumbent stone circle')]
# [('type', 'http://www.wikidata.org/entity/Q5464137'), ('typeName', 'Fogou')]
# [('type', 'http://www.wikidata.org/entity/Q1016247'), ('typeName', 'Burgward')]
# [('type', 'http://www.wikidata.org/entity/Q6024699'), ('typeName', 'motilla')]
# [('type', 'http://www.wikidata.org/entity/Q36539'), ('typeName', 'oven')]
# [('type', 'http://www.wikidata.org/entity/Q15069452'), ('typeName', 'Natura 2000 protected area')]
# [('type', 'http://www.wikidata.org/entity/Q1408475'), ('typeName', 'fortified house')]
# [('type', 'http://www.wikidata.org/entity/Q748'), ('typeName', 'Buddhism')]
# [('type', 'http://www.wikidata.org/entity/Q8148'), ('typeName', 'industry')]
# [('type', 'http://www.wikidata.org/entity/Q1140316'), ('typeName', 'penal colony')]
# [('type', 'http://www.wikidata.org/entity/Q2347389'), ('typeName', 'Government House')]
# [('type', 'http://www.wikidata.org/entity/Q37901'), ('typeName', 'strait')]
# [('type', 'http://www.wikidata.org/entity/Q175185'), ('typeName', 'rural area')]
# [('type', 'http://www.wikidata.org/entity/Q52063204'), ('typeName', 'parque provincial (Argentina)')]
# [('type', 'http://www.wikidata.org/entity/Q555911'), ('typeName', 'private property')]
# [('type', 'http://www.wikidata.org/entity/Q64219648'), ('typeName', 'Kindergarten')]
# [('type', 'http://www.wikidata.org/entity/Q41767843'), ('typeName', 'sunken vessel')]
# [('type', 'http://www.wikidata.org/entity/Q279616'), ('typeName', 'Horreum')]
# [('type', 'http://www.wikidata.org/entity/Q96382534'), ('typeName', 'mosque ruin')]
# [('type', 'http://www.wikidata.org/entity/Q1165999'), ('typeName', 'lake freighter')]
# [('type', 'http://www.wikidata.org/entity/Q16670127'), ('typeName', 'Battery (monument)')]
# [('type', 'http://www.wikidata.org/entity/Q811165'), ('typeName', 'architectural heritage monument')]
# [('type', 'http://www.wikidata.org/entity/Q11411019'), ('typeName', 'kofungun')]
# [('type', 'http://www.wikidata.org/entity/Q31855'), ('typeName', 'research institute')]
# [('type', 'http://www.wikidata.org/entity/Q478798'), ('typeName', 'image')]
# [('type', 'http://www.wikidata.org/entity/Q3748441'), ('typeName', 'forum venalium')]
# [('type', 'http://www.wikidata.org/entity/Q19479037'), ('typeName', 'sculpture series')]
# [('type', 'http://www.wikidata.org/entity/Q1356770'), ('typeName', 'Heroön')]
# [('type', 'http://www.wikidata.org/entity/Q5615741'), ('typeName', 'latrine')]
# [('type', 'http://www.wikidata.org/entity/Q570600'), ('typeName', 'listed building in the United Kingdom')]
# [('type', 'http://www.wikidata.org/entity/Q17343829'), ('typeName', 'unincorporated community in the United States')]
# [('type', 'http://www.wikidata.org/entity/Q27067659'), ('typeName', 'former river')]
# [('type', 'http://www.wikidata.org/entity/Q1247867'), ('typeName', 'housing')]
# [('type', 'http://www.wikidata.org/entity/Q513550'), ('typeName', 'hermitage')]
# [('type', 'http://www.wikidata.org/entity/Q1385463'), ('typeName', 'acequia')]
# [('type', 'http://www.wikidata.org/entity/Q47928'), ('typeName', 'circus')]
# [('type', 'http://www.wikidata.org/entity/Q9065054'), ('typeName', 'Granaries in Spain')]
# [('type', 'http://www.wikidata.org/entity/Q725453'), ('typeName', 'peristyle')]
# [('type', 'http://www.wikidata.org/entity/Q63127402'), ('typeName', 'domestic architecture')]
# [('type', 'http://www.wikidata.org/entity/Q1154112'), ('typeName', 'Grand site de France')]
# [('type', 'http://www.wikidata.org/entity/Q844619'), ('typeName', 'Vihara')]
# [('type', 'http://www.wikidata.org/entity/Q555937'), ('typeName', 'tidal island')]
# [('type', 'http://www.wikidata.org/entity/Q43501'), ('typeName', 'zoo')]
# [('type', 'http://www.wikidata.org/entity/Q14276458'), ('typeName', 'deck arch bridge')]
# [('type', 'http://www.wikidata.org/entity/Q542261'), ('typeName', 'Mughal architecture')]
# [('type', 'http://www.wikidata.org/entity/Q90754'), ('typeName', 'redoubt')]
# [('type', 'http://www.wikidata.org/entity/Q2988353'), ('typeName', 'verraco')]
# [('type', 'http://www.wikidata.org/entity/Q2940297'), ('typeName', 'limestone quarry')]
# [('type', 'http://www.wikidata.org/entity/Q6498684'), ('typeName', 'ownership')]
# [('type', 'http://www.wikidata.org/entity/Q21751045'), ('typeName', 'former cemetery')]
# [('type', 'http://www.wikidata.org/entity/Q29968390'), ('typeName', 'landscape of religious buildings')]
# [('type', 'http://www.wikidata.org/entity/Q2322432'), ('typeName', 'Nagar Panchayat')]
# [('type', 'http://www.wikidata.org/entity/Q14616455'), ('typeName', 'destroyed city')]
# [('type', 'http://www.wikidata.org/entity/Q1365179'), ('typeName', 'private mansion')]
# [('type', 'http://www.wikidata.org/entity/Q11500'), ('typeName', 'area')]
# [('type', 'http://www.wikidata.org/entity/Q12046110'), ('typeName', 'burial chamber')]
# [('type', 'http://www.wikidata.org/entity/Q16537979'), ('typeName', 'castelliere')]
# [('type', 'http://www.wikidata.org/entity/Q1575478'), ('typeName', 'hillside castle')]
# [('type', 'http://www.wikidata.org/entity/Q3094719'), ('typeName', 'galgal')]
# [('type', 'http://www.wikidata.org/entity/Q185600'), ('typeName', 'portico')]
# [('type', 'http://www.wikidata.org/entity/Q959309'), ('typeName', 'coal mine')]
# [('type', 'http://www.wikidata.org/entity/Q114768'), ('typeName', 'granary')]
# [('type', 'http://www.wikidata.org/entity/Q9358347'), ('typeName', 'theatron')]
# [('type', 'http://www.wikidata.org/entity/Q163740'), ('typeName', 'nonprofit organization')]
# [('type', 'http://www.wikidata.org/entity/Q21505397'), ('typeName', 'motor yacht')]
# [('type', 'http://www.wikidata.org/entity/Q28843552'), ('typeName', 'factory complex')]
# [('type', 'http://www.wikidata.org/entity/Q107690225'), ('typeName', 'Paratge natural municipal')]
# [('type', 'http://www.wikidata.org/entity/Q4463341'), ('typeName', 'underground living')]
# [('type', 'http://www.wikidata.org/entity/Q385422'), ('typeName', 'powder mill')]
# [('type', 'http://www.wikidata.org/entity/Q683363'), ('typeName', 'cutter')]
# [('type', 'http://www.wikidata.org/entity/Q985843'), ('typeName', 'artificial reef')]
# [('type', 'http://www.wikidata.org/entity/Q105197922'), ('typeName', 'slave cemetery')]
# [('type', 'http://www.wikidata.org/entity/Q16329119'), ('typeName', 'Arula - Louvre CA 5956')]
# [('type', 'http://www.wikidata.org/entity/Q916333'), ('typeName', 'Rijksmonument')]
# [('type', 'http://www.wikidata.org/entity/Q9381142'), ('typeName', 'hill chain')]
# [('type', 'http://www.wikidata.org/entity/Q191826'), ('typeName', 'tug')]
# [('type', 'http://www.wikidata.org/entity/Q1492017'), ('typeName', 'gallows hill')]
# [('type', 'http://www.wikidata.org/entity/Q2890064'), ('typeName', 'ditch')]
# [('type', 'http://www.wikidata.org/entity/Q3199915'), ('typeName', 'massacre')]
# [('type', 'http://www.wikidata.org/entity/Q27654220'), ('typeName', 'abandoned hamlet')]
# [('type', 'http://www.wikidata.org/entity/Q10396778'), ('typeName', 'fishing ground')]
# [('type', 'http://www.wikidata.org/entity/Q297163'), ('typeName', 'oil mill')]
# [('type', 'http://www.wikidata.org/entity/Q3177968'), ('typeName', 'vivarium')]
# [('type', 'http://www.wikidata.org/entity/Q446828'), ('typeName', 'chapel of Loreto')]
# [('type', 'http://www.wikidata.org/entity/Q1161819'), ('typeName', 'Ancient Roman unit of measurement')]
# [('type', 'http://www.wikidata.org/entity/Q16518'), ('typeName', 'barge')]
# [('type', 'http://www.wikidata.org/entity/Q1179791'), ('typeName', 'glassworks')]
# [('type', 'http://www.wikidata.org/entity/Q861951'), ('typeName', 'police station')]
# [('type', 'http://www.wikidata.org/entity/Q361945'), ('typeName', 'slipway')]
# [('type', 'http://www.wikidata.org/entity/Q24933318'), ('typeName', 'Gallo-Roman amphitheatre')]
# [('type', 'http://www.wikidata.org/entity/Q189265'), ('typeName', 'atrium')]
# [('type', 'http://www.wikidata.org/entity/Q2060938'), ('typeName', 'taberna')]
# [('type', 'http://www.wikidata.org/entity/Q62059246'), ('typeName', 'public reserve')]
# [('type', 'http://www.wikidata.org/entity/Q927825'), ('typeName', 'mortuary temple')]
# [('type', 'http://www.wikidata.org/entity/Q175208'), ('typeName', 'biotope')]
# [('type', 'http://www.wikidata.org/entity/Q60129'), ('typeName', 'monopteros')]
# [('type', 'http://www.wikidata.org/entity/Q25391'), ('typeName', 'dune')]
# [('type', 'http://www.wikidata.org/entity/Q386724'), ('typeName', 'work')]
# [('type', 'http://www.wikidata.org/entity/Q20034791'), ('typeName', 'defensive tower')]
# [('type', 'http://www.wikidata.org/entity/Q1183485'), ('typeName', 'pinge')]
# 1117

# %% [markdown]
# And using regex I can filter for something particular.

# %%
queryString = """
select distinct ?type ?typeName where {
    # ?arch wdt:P31 wd:Q839954 ;
          wdt:P31 ?type .
    
    # ?type <http://schema.org/name> ?typeName .
    
    filter (regex(?typeName, "theatre|settlement", "i"))
}
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('type', 'http://www.wikidata.org/entity/Q14601169'), ('typeName', 'human fortified settlement')]
# [('type', 'http://www.wikidata.org/entity/Q1708422'), ('typeName', 'settlement site')]
# [('type', 'http://www.wikidata.org/entity/Q7362268'), ('typeName', 'Roman amphitheatre')]
# [('type', 'http://www.wikidata.org/entity/Q486972'), ('typeName', 'human settlement')]
# [('type', 'http://www.wikidata.org/entity/Q2860319'), ('typeName', 'Greek theatre')]
# [('type', 'http://www.wikidata.org/entity/Q19757'), ('typeName', 'Roman theatre')]
# [('type', 'http://www.wikidata.org/entity/Q24354'), ('typeName', 'theatre')]
# [('type', 'http://www.wikidata.org/entity/Q106468588'), ('typeName', 'Jewish settlement in the land of Israel')]
# [('type', 'http://www.wikidata.org/entity/Q2844395'), ('typeName', 'Avenches amphitheatre')]
# [('type', 'http://www.wikidata.org/entity/Q100268926'), ('typeName', 'iberian settlement')]
# [('type', 'http://www.wikidata.org/entity/Q2264924'), ('typeName', 'port settlement')]
# [('type', 'http://www.wikidata.org/entity/Q54831'), ('typeName', 'amphitheatre')]
# [('type', 'http://www.wikidata.org/entity/Q3467688'), ('typeName', 'Ancient settlements in Turkey')]
# [('type', 'http://www.wikidata.org/entity/Q60995739'), ('typeName', 'moated settlement')]
# [('type', 'http://www.wikidata.org/entity/Q19285917'), ('typeName', 'hilltop settlement')]
# [('type', 'http://www.wikidata.org/entity/Q17645016'), ('typeName', 'Iron Age settlement')]
# [('type', 'http://www.wikidata.org/entity/Q106626840'), ('typeName', 'historical settlement')]
# [('type', 'http://www.wikidata.org/entity/Q24933318'), ('typeName', 'Gallo-Roman amphitheatre')]
# 18

# %% [markdown]
# And of course I can use property paths to looks for instances and subclasses iteratively.

# %% [markdown]
# ## 3. Is there any relevant numerical attribute that describes these sites, e.g., number visitors?

# %% [markdown]
# For relevant numerical attributes, I can list the numerical properties of archeological sites.

# %%
queryString = """
select distinct ?p ?pName where {
    # ?arch wdt:P31 wd:Q839954 ;
          # ?p ?o .
    
    # ?p <http://schema.org/name> ?pName .
    filter (isNumeric(?o))
}
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P1082'), ('pName', 'population')]
# [('p', 'http://www.wikidata.org/prop/direct/P2043'), ('pName', 'length')]
# [('p', 'http://www.wikidata.org/prop/direct/P2044'), ('pName', 'elevation above sea level')]
# [('p', 'http://www.wikidata.org/prop/direct/P2046'), ('pName', 'area')]
# [('p', 'http://www.wikidata.org/prop/direct/P2048'), ('pName', 'height')]
# [('p', 'http://www.wikidata.org/prop/direct/P2049'), ('pName', 'width')]
# [('p', 'http://www.wikidata.org/prop/direct/P2109'), ('pName', 'installed capacity')]
# [('p', 'http://www.wikidata.org/prop/direct/P4511'), ('pName', 'vertical depth')]
# [('p', 'http://www.wikidata.org/prop/direct/P8687'), ('pName', 'social media followers')]
# [('p', 'http://www.wikidata.org/prop/direct/P1174'), ('pName', 'visitors per year')]
# [('p', 'http://www.wikidata.org/prop/direct/P2130'), ('pName', 'cost')]
# [('p', 'http://www.wikidata.org/prop/direct/P1538'), ('pName', 'number of households')]
# [('p', 'http://www.wikidata.org/prop/direct/P2234'), ('pName', 'volume as quantity')]
# [('p', 'http://www.wikidata.org/prop/direct/P2660'), ('pName', 'topographic prominence')]
# [('p', 'http://www.wikidata.org/prop/direct/P2659'), ('pName', 'topographic isolation')]
# [('p', 'http://www.wikidata.org/prop/direct/P2324'), ('pName', 'quantity buried')]
# [('p', 'http://www.wikidata.org/prop/direct/P1083'), ('pName', 'maximum capacity')]
# [('p', 'http://www.wikidata.org/prop/direct/P1539'), ('pName', 'female population')]
# [('p', 'http://www.wikidata.org/prop/direct/P1540'), ('pName', 'male population')]
# [('p', 'http://www.wikidata.org/prop/direct/P2610'), ('pName', 'thickness')]
# [('p', 'http://www.wikidata.org/prop/direct/P2555'), ('pName', 'fee')]
# [('p', 'http://www.wikidata.org/prop/direct/P2261'), ('pName', 'beam')]
# [('p', 'http://www.wikidata.org/prop/direct/P2262'), ('pName', 'draft')]
# [('p', 'http://www.wikidata.org/prop/direct/P1101'), ('pName', 'floors above ground')]
# [('p', 'http://www.wikidata.org/prop/direct/P1314'), ('pName', 'number of spans')]
# [('p', 'http://www.wikidata.org/prop/direct/P2787'), ('pName', 'longest span')]
# [('p', 'http://www.wikidata.org/prop/direct/P6801'), ('pName', 'number of hospital beds')]
# [('p', 'http://www.wikidata.org/prop/direct/P2386'), ('pName', 'diameter')]
# [('p', 'http://www.wikidata.org/prop/direct/P6498'), ('pName', 'illiterate population')]
# [('p', 'http://www.wikidata.org/prop/direct/P6499'), ('pName', 'literate population')]
# [('p', 'http://www.wikidata.org/prop/direct/P2927'), ('pName', 'water as percent of area')]
# [('p', 'http://www.wikidata.org/prop/direct/P2923'), ('pName', 'focal height')]
# [('p', 'http://www.wikidata.org/prop/direct/P2929'), ('pName', 'lighthouse range')]
# [('p', 'http://www.wikidata.org/prop/direct/P2547'), ('pName', 'perimeter')]
# [('p', 'http://www.wikidata.org/prop/direct/P4080'), ('pName', 'number of houses')]
# [('p', 'http://www.wikidata.org/prop/direct/P2067'), ('pName', 'mass')]
# [('p', 'http://www.wikidata.org/prop/direct/P2053'), ('pName', 'watershed area')]
# [('p', 'http://www.wikidata.org/prop/direct/P1139'), ('pName', 'floors below ground')]
# [('p', 'http://www.wikidata.org/prop/direct/P1093'), ('pName', 'gross tonnage')]
# [('p', 'http://www.wikidata.org/prop/direct/P1120'), ('pName', 'number of deaths')]
# [('p', 'http://www.wikidata.org/prop/direct/P2052'), ('pName', 'speed')]
# 41

# %% [markdown]
# There are some relevant attributes releated to the archeological sites, like the *visitors per year (**P1174**)*, the *cost (**P2130**)*, the *area (**P2046**)* or the *maximum capacity (**P1083**)*.

# %% [markdown]
# ## 4.1. Which country has more archaeological sites? Which country has the most human settlements?

# %% [markdown]
# For what concern the archaeological sites, I can simply use the BGP defined in the first section

# %%
queryString = """
select ?country ?countryName (count(?arch) as ?numSites) where {
    # ?arch wdt:P31+/wdt:P279* wd:Q839954 ;
          wdt:P17 ?country .
    
    # ?country <http://schema.org/name> ?countryName .
} group by ?country ?countryName
order by desc(?numSites)
limit 1
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('country', 'http://www.wikidata.org/entity/Q34'), ('countryName', 'Sweden'), ('numSites', '80859')]
# 1

# %% [markdown]
# Sweden is the country with the highest number of archaeological sites. For what concern the human settlements, from point 2, the human settlement is described by entity **Q486972**.

# %%
queryString = """
select ?country ?countryName (count(distinct ?settlement) as ?numSettlements) where {
    # ?settlement wdt:P31+/wdt:P279* wd:Q486972 ;
                wdt:P17 ?country .
    
    # ?country <http://schema.org/name> ?countryName .
} group by ?country ?countryName
order by desc(?numSettlements)
limit 1
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('country', 'http://www.wikidata.org/entity/Q148'), ('countryName', "People's Republic of China"), ('numSettlements', '704508')]
# 1

# %% [markdown]
# RPC is the country with the highest number of human settlements

# %% [markdown]
# ## 4.2. Which countries have Ancient Rome sites, which other "archaeological cultures" are described?

# %% [markdown]
# I can get the countries with Ancient Rome sites looking for the culture of archaeological sites, using the BGP defined in the first section. I can also list the continent of these sites, to check if there are not uncongrous data, since it would be strange to have Ancient Rome sites, for example, in America.

# %%
queryString = """
select ?country ?countryName (group_concat(distinct ?continentName; separator=", ") as ?continents) (count(distinct ?site) as ?numSites) where {
    # ?site wdt:P31+/wdt:P279* wd:Q839954 ;
          wdt:P2596 wd:Q1747689 ;
          wdt:P17 ?country .
    
    # ?country wdt:P30 ?continent .
    
    # ?country <http://schema.org/name> ?countryName .
    # ?continent <http://schema.org/name> ?continentName .
} group by ?country ?countryName
order by desc(?numSites)
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('country', 'http://www.wikidata.org/entity/Q38'), ('countryName', 'Italy'), ('continents', 'Europe'), ('numSites', '502')]
# [('country', 'http://www.wikidata.org/entity/Q142'), ('countryName', 'France'), ('continents', 'Europe'), ('numSites', '58')]
# [('country', 'http://www.wikidata.org/entity/Q29'), ('countryName', 'Spain'), ('continents', 'Europe'), ('numSites', '53')]
# [('country', 'http://www.wikidata.org/entity/Q948'), ('countryName', 'Tunisia'), ('continents', 'Africa'), ('numSites', '29')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryName', 'United Kingdom'), ('continents', 'Europe'), ('numSites', '27')]
# [('country', 'http://www.wikidata.org/entity/Q183'), ('countryName', 'Germany'), ('continents', 'Europe'), ('numSites', '21')]
# [('country', 'http://www.wikidata.org/entity/Q219'), ('countryName', 'Bulgaria'), ('continents', 'Europe'), ('numSites', '9')]
# [('country', 'http://www.wikidata.org/entity/Q1747689'), ('countryName', 'Ancient Rome'), ('continents', 'Africa, Asia, Europe'), ('numSites', '9')]
# [('country', 'http://www.wikidata.org/entity/Q41'), ('countryName', 'Greece'), ('continents', 'Europe'), ('numSites', '8')]
# [('country', 'http://www.wikidata.org/entity/Q218'), ('countryName', 'Romania'), ('continents', 'Europe'), ('numSites', '8')]
# [('country', 'http://www.wikidata.org/entity/Q262'), ('countryName', 'Algeria'), ('continents', 'Africa'), ('numSites', '8')]
# [('country', 'http://www.wikidata.org/entity/Q43'), ('countryName', 'Turkey'), ('continents', 'Asia, Eurasia, Europe'), ('numSites', '8')]
# [('country', 'http://www.wikidata.org/entity/Q40'), ('countryName', 'Austria'), ('continents', 'Europe'), ('numSites', '8')]
# [('country', 'http://www.wikidata.org/entity/Q1016'), ('countryName', 'Libya'), ('continents', 'Africa'), ('numSites', '7')]
# [('country', 'http://www.wikidata.org/entity/Q801'), ('countryName', 'Israel'), ('continents', 'Asia'), ('numSites', '6')]
# [('country', 'http://www.wikidata.org/entity/Q45'), ('countryName', 'Portugal'), ('continents', 'Europe'), ('numSites', '5')]
# [('country', 'http://www.wikidata.org/entity/Q39'), ('countryName', 'Switzerland'), ('continents', 'Europe'), ('numSites', '5')]
# [('country', 'http://www.wikidata.org/entity/Q403'), ('countryName', 'Serbia'), ('continents', 'Europe'), ('numSites', '5')]
# [('country', 'http://www.wikidata.org/entity/Q224'), ('countryName', 'Croatia'), ('continents', 'Europe'), ('numSites', '5')]
# [('country', 'http://www.wikidata.org/entity/Q858'), ('countryName', 'Syria'), ('continents', 'Asia'), ('numSites', '4')]
# [('country', 'http://www.wikidata.org/entity/Q28'), ('countryName', 'Hungary'), ('continents', 'Europe'), ('numSites', '4')]
# [('country', 'http://www.wikidata.org/entity/Q79'), ('countryName', 'Egypt'), ('continents', 'Africa, Asia'), ('numSites', '3')]
# [('country', 'http://www.wikidata.org/entity/Q55'), ('countryName', 'Netherlands'), ('continents', 'Central America, Europe'), ('numSites', '2')]
# [('country', 'http://www.wikidata.org/entity/Q1028'), ('countryName', 'Morocco'), ('continents', 'Africa'), ('numSites', '2')]
# [('country', 'http://www.wikidata.org/entity/Q229'), ('countryName', 'Cyprus'), ('continents', 'Asia, Europe'), ('numSites', '2')]
# [('country', 'http://www.wikidata.org/entity/Q810'), ('countryName', 'Jordan'), ('continents', 'Asia'), ('numSites', '2')]
# [('country', 'http://www.wikidata.org/entity/Q12544'), ('countryName', 'Byzantine Empire'), ('continents', 'Africa, Asia, Europe'), ('numSites', '1')]
# [('country', 'http://www.wikidata.org/entity/Q222'), ('countryName', 'Albania'), ('continents', 'Europe'), ('numSites', '1')]
# [('country', 'http://www.wikidata.org/entity/Q31'), ('countryName', 'Belgium'), ('continents', 'Europe'), ('numSites', '1')]
# [('country', 'http://www.wikidata.org/entity/Q32'), ('countryName', 'Luxembourg'), ('continents', 'Europe'), ('numSites', '1')]
# [('country', 'http://www.wikidata.org/entity/Q233'), ('countryName', 'Malta'), ('continents', 'Europe'), ('numSites', '1')]
# [('country', 'http://www.wikidata.org/entity/Q230'), ('countryName', 'Georgia'), ('continents', 'Asia, Europe'), ('numSites', '1')]
# [('country', 'http://www.wikidata.org/entity/Q213'), ('countryName', 'Czech Republic'), ('continents', 'Europe'), ('numSites', '1')]
# 33

# %% [markdown]
# And then, the others archaeological cultures which leaved in the same place of ancient romans are:

# %%
queryString = """
select distinct ?culture ?cultureName where {
    # ?site wdt:P31+/wdt:P279* wd:Q839954 ;
          wdt:P2596 wd:Q1747689 ;
          wdt:P2596 ?culture ;
          wdt:P17 ?country .
    
    # ?culture <http://schema.org/name> ?cultureName .
}
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('culture', 'http://www.wikidata.org/entity/Q1747689'), ('cultureName', 'Ancient Rome')]
# [('culture', 'http://www.wikidata.org/entity/Q530894'), ('cultureName', 'Talaiotic Culture')]
# [('culture', 'http://www.wikidata.org/entity/Q5011445'), ('cultureName', 'Celtiberians')]
# [('culture', 'http://www.wikidata.org/entity/Q45315'), ('cultureName', 'Berbers')]
# [('culture', 'http://www.wikidata.org/entity/Q4383747'), ('cultureName', 'Punics')]
# [('culture', 'http://www.wikidata.org/entity/Q11772'), ('cultureName', 'Ancient Greece')]
# [('culture', 'http://www.wikidata.org/entity/Q12544'), ('cultureName', 'Byzantine Empire')]
# [('culture', 'http://www.wikidata.org/entity/Q1200427'), ('cultureName', 'culture of ancient Rome')]
# [('culture', 'http://www.wikidata.org/entity/Q22633'), ('cultureName', 'Germanic peoples')]
# [('culture', 'http://www.wikidata.org/entity/Q220379'), ('cultureName', 'Adriatic Veneti')]
# [('culture', 'http://www.wikidata.org/entity/Q582861'), ('cultureName', 'Marinid Dynasty')]
# [('culture', 'http://www.wikidata.org/entity/Q93180'), ('cultureName', 'Seleucid Empire')]
# [('culture', 'http://www.wikidata.org/entity/Q773818'), ('cultureName', 'Unetice culture')]
# [('culture', 'http://www.wikidata.org/entity/Q208247'), ('cultureName', 'La Tène culture')]
# 14

# %% [markdown]
# ## 4.3. Which country has the most diverse set of civilizations or cultures across its sites?

# %% [markdown]
# In order to answer this question, I can get the culture releated to the sites and group by country.

# %%
queryString = """
select ?country ?countryName (count(distinct ?culture) as ?numCultures) where {
    # ?site wdt:P31+/wdt:P279* wd:Q839954 ;
          wdt:P2596 ?culture ;
          wdt:P17 ?country .
    
    # ?country <http://schema.org/name> ?countryName .
} group by ?country ?countryName
order by desc(?numCultures)
limit 1
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('country', 'http://www.wikidata.org/entity/Q38'), ('countryName', 'Italy'), ('numCultures', '62')]
# 1

# %% [markdown]
# Italy is the country with most diverse set of civilizations and cultures across its sites. In the next query I will also list these cultures.

# %%
queryString = """
select distinct ?culture ?cultureName where {
    # ?site wdt:P31+/wdt:P279* wd:Q839954 ;
          wdt:P2596 ?culture ;
          wdt:P17 wd:Q38 .
    
    # ?culture <http://schema.org/name> ?cultureName .
}
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [
# [('culture', 'http://www.wikidata.org/entity/Q20971658'), ('cultureName', 'pre-roman')]
# [('culture', 'http://www.wikidata.org/entity/Q643335'), ('cultureName', 'Abealzu-Filigosa culture')]
# [('culture', 'http://www.wikidata.org/entity/Q3007186'), ('cultureName', 'Arzachena culture')]
# [('culture', 'http://www.wikidata.org/entity/Q1265446'), ('cultureName', 'Marsi')]
# [('culture', 'http://www.wikidata.org/entity/Q83418'), ('cultureName', 'Normans')]
# [('culture', 'http://www.wikidata.org/entity/Q33849736'), ('cultureName', 'Culture of Pantalica')]
# [('culture', 'http://www.wikidata.org/entity/Q931423'), ('cultureName', 'Elymians')]
# [('culture', 'http://www.wikidata.org/entity/Q487908'), ('cultureName', 'Osci')]
# [('culture', 'http://www.wikidata.org/entity/Q3589150'), ('cultureName', 'Epigravettian')]
# [('culture', 'http://www.wikidata.org/entity/Q746287'), ('cultureName', 'Oldowan')]
# [('culture', 'http://www.wikidata.org/entity/Q925746'), ('cultureName', 'Caraceni')]
# [('culture', 'http://www.wikidata.org/entity/Q737684'), ('cultureName', 'Messapii')]
# [('culture', 'http://www.wikidata.org/entity/Q2301209'), ('cultureName', 'prehistoric Italy')]
# [('culture', 'http://www.wikidata.org/entity/Q1165749'), ('cultureName', 'Marrucini')]
# [('culture', 'http://www.wikidata.org/entity/Q4383747'), ('cultureName', 'Punics')]
# [('culture', 'http://www.wikidata.org/entity/Q2511062'), ('cultureName', 'Square Mouthed Vases culture')]
# [('culture', 'http://www.wikidata.org/entity/Q994847'), ('cultureName', 'Bruttii')]
# [('culture', 'http://www.wikidata.org/entity/Q1585136'), ('cultureName', 'Monte Claro culture')]
# [('culture', 'http://www.wikidata.org/entity/Q777462'), ('cultureName', 'Aurunci')]
# [('culture', 'http://www.wikidata.org/entity/Q1200427'), ('cultureName', 'culture of ancient Rome')]
# [('culture', 'http://www.wikidata.org/entity/Q4948'), ('cultureName', 'Republic of Venice')]
# [('culture', 'http://www.wikidata.org/entity/Q11761'), ('cultureName', 'Bronze Age')]
# [('culture', 'http://www.wikidata.org/entity/Q1473758'), ('cultureName', 'Ozieri culture')]
# [('culture', 'http://www.wikidata.org/entity/Q3723502'), ('cultureName', 'Hellenes')]
# [('culture', 'http://www.wikidata.org/entity/Q40203'), ('cultureName', 'paleolithic')]
# [('culture', 'http://www.wikidata.org/entity/Q14618893'), ('cultureName', 'history of the Roman Empire from 27 BCE to 395 AD')]
# [('culture', 'http://www.wikidata.org/entity/Q3699313'), ('cultureName', 'Castelluccio Culture')]
# [('culture', 'http://www.wikidata.org/entity/Q3617880'), ('cultureName', 'Italic peoples')]
# [('culture', 'http://www.wikidata.org/entity/Q663655'), ('cultureName', 'Volsci')]
# [('culture', 'http://www.wikidata.org/entity/Q12544'), ('cultureName', 'Byzantine Empire')]
# 62

# %% [markdown]
# ## 4.4. If you are interested in visiting some sites, which country would you pick? Based on what criteria?

# %% [markdown]
# If I want to visit a country based on its archaeological sites, I can consider different criterias to chose the best one. For example, I can consider the number of cultures in the country, as done for the point 4.3. Another parameter can be the number of archeological sites, as done in point 4.1. I can also consider the number of visitors per year, that can give an idea of the popularity of the site.

# %% [markdown]
# I can also merge all these parameters together, assigning to each country a point based on the following formula:
#
# ```
# a * avg(numVisitorsPerYear) + b * numArchaeologicalSites + c * numCultures
# ```
#
# With `a`, `b`, `c` the weight for each criteria.

# %% [markdown]
# For example, with a = 0.75, b = 1 and c = 0.5, we can discover which is the preferred country to visit, based on this preferences

# %%
queryString = """
select ?country ?countryName ?score where {
    {
        select ?country (count(distinct ?site) as ?numSites) (count(distinct ?culture) as ?numCultures) (avg(?visitorsPerYear) as ?avgVisitors) where {
            # ?site wdt:P31+/wdt:P279* wd:Q839954 ;
                  wdt:P17 ?country .

            optional { ?site wdt:P2596 ?culture } .
            optional { ?site wdt:P1174 ?visitorsPerYear filter (isNumeric(?visitorsPerYear)) } .
        } group by ?country
    } .
    
    bind (if(?avgVisitors, ?avgVisitors, 0) as ?avgVisitorsInt) .
    bind ((?avgVisitorsInt * 0.7 + ?numSites + ?numCultures * 0.5) as ?score) .
    
    # ?country <http://schema.org/name> ?countryName .
} order by desc(?score)
limit 1
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('country', 'http://www.wikidata.org/entity/Q38'), ('countryName', 'Italy'), ('score', '12336301.616666666666667')]
# 1

# %% [markdown]
# And the best country to visit for archaeological sites, number of visitors and number of cultures is Italy.

# %% [markdown]
# If I am interested also only in some types of archeological sites, such as amphitheatre, I can add a filter or using a different BGP. For the example of amphitheatre, I can use:

# %%
queryString = """
select ?country ?countryName ?score where {
    {
        select ?country (count(distinct ?site) as ?numSites) (count(distinct ?culture) as ?numCultures) (avg(?visitorsPerYear) as ?avgVisitors) where {
            # ?site wdt:P31+/wdt:P279* wd:Q54831 ;
                  wdt:P17 ?country .

            optional { ?site wdt:P2596 ?culture } .
            optional { ?site wdt:P1174 ?visitorsPerYear filter (isNumeric(?visitorsPerYear)) } .
        } group by ?country
    } .
    
    bind (if(?avgVisitors, ?avgVisitors, 0) as ?avgVisitorsInt) .
    
    bind ((?avgVisitorsInt * 0.7 + ?numSites + ?numCultures * 0.5) as ?score) .
    
    # ?country <http://schema.org/name> ?countryName .
} order by desc(?score)
limit 1
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('country', 'http://www.wikidata.org/entity/Q38'), ('countryName', 'Italy'), ('score', '5180120.5')]
# 1

# %% [markdown]
# And also in this case, Italy is the best choice.
#
# Finally, I can also do another example, hypothesizing I am interested in mosque (**Q32815**)

# %%
queryString = """
select ?country ?countryName ?score where {
    {
        select ?country (count(distinct ?site) as ?numSites) (count(distinct ?culture) as ?numCultures) (avg(?visitorsPerYear) as ?avgVisitors) where {
            # ?site wdt:P31+/wdt:P279* wd:Q32815 ;
                  wdt:P17 ?country .

            optional { ?site wdt:P2596 ?culture } .
            optional { ?site wdt:P1174 ?visitorsPerYear filter (isNumeric(?visitorsPerYear))} .
        } group by ?country
    } .
    
    bind (if(?avgVisitors, ?avgVisitors, 0) as ?avgVisitorsInt) .
    
    bind ((?avgVisitorsInt * 0.7 + ?numSites + ?numCultures * 0.5) as ?score) .
    
    # ?country <http://schema.org/name> ?countryName .
} order by desc(?score)
limit 1
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('country', 'http://www.wikidata.org/entity/Q29'), ('countryName', 'Spain'), ('score', '980072')]
# 1

# %% [markdown]
# And in this case the best choice is Spain.

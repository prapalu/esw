# %% [markdown]
# # General instructions
#
# The goal of the project is to materialize a set of **exploratory workloads** over a real-world, large-scale,  open-domain KG: [WikiData](https://www.wikidata.org/wiki/Wikidata:Main_Page)
#
# An exploratory workload  is composed by a set of queries, where each query is related to the information obtained previously.
#
# An exploratory workload starts with a usually vague, open ended question, and does not assume the person issuing the workload has a clear understanding of the data contained in the target database or its structure.
#
# Remeber that:
#
# 1. All the queries must run in the python notebook
# 2. You can use classes and properties only if you find them via a SPARQL query that must be present in the notebook
# 3. You do not delete useless queries. Keep everything that is synthatically valid
#
# ```
# ?p <http://schema.org/name> ?name .
# ```
#
#     is the BGP returning a human-readable name of a property or a class in Wikidata.

# %%
## SETUP used later

from SPARQLWrapper import SPARQLWrapper, JSON


prefixString = """
##-ab8f3961c4-##
PREFIX wd: <http://www.wikidata.org/entity/> 
PREFIX wdt: <http://www.wikidata.org/prop/direct/> 
PREFIX sc: <http://schema.org/>
"""

# select and construct queries
def run_query(queryString):
    to_run = prefixString + "\n" + queryString

    sparql = SPARQLWrapper("http://a256-gc1-02.srv.aau.dk:5820/sparql")
    sparql.setTimeout(300)
    sparql.setReturnFormat(JSON)
    sparql.setQuery(to_run)

    try :
       results = sparql.query()
       json_results = results.convert()
       if len(json_results['results']['bindings'])==0:
          print("Empty")
          return 0
    
       for bindings in json_results['results']['bindings']:
          print( [ (var, value['value'])  for var, value in bindings.items() ] )

       return len(json_results['results']['bindings'])

    except Exception as e :
        print("The operation failed", e)
    
# ASk queries
def run_ask_query(queryString):
    to_run = prefixString + "\n" + queryString

    sparql = SPARQLWrapper("http://a256-gc1-02.srv.aau.dk:5820/sparql")
    sparql.setTimeout(300)
    sparql.setReturnFormat(JSON)
    sparql.setQuery(to_run)

    try :
        return sparql.query().convert()

    except Exception as e :
        print("The operation failed", e)

# %% [markdown]
# # Book Workflow Series ("Nobel laureates explorative search")
#
#
# Consider the following exploratory scenario:
#
# >  Investigate the authors who won the Nobel award for literature and get information about the nationality of the winners and analyse their literary production
#
#
#
# ## Useful URIs for the current workflow
# The following are given:
#
# | IRI           | Description   | Role      |
# | -----------   | -----------   |-----------|
# | `wdt:P1647`   | subproperty   | predicate |
# | `wdt:P31`     | instance of   | predicate |
# | `wdt:P106`    | profession    | predicate |
# | `wdt:P279`    | subclass      | predicate |
# | `wdt:P17`     | country       | predicate |
# | `wdt:P27`     | citizenship   | predicate |
# | `wd:Q37922`   | Nobel Prize in Literature     | node |
# | `wd:Q36180`   | writer        | node |
# | `wd:Q38`      | Italy         | node |
# | `wd:Q3624078` | Sovereign state  | node |
# | `wd:Q213678`  | Vatican Library  | node |
#
#
# Also consider
#
# ```
# ?p wdt:P27 wd:Q38  .
# ?p wdt:P106/wdt:P279* wd:Q36180  .
# ```
#
# is the BGP to retrieve all **italian authors**
#
# The workload should
#
#
# 1. Identify the BGP for obtaining the nobel laureates and the nominees with their relevant attributes
#
# 2. Get the number of Italian, French and Iranian winners and check which nation won more awards in the last twenty years.
#
# 3. Determine how many Literature nobel laureates have the following contries: Italy, Germany, France, Romania, Denmark, Iran, and China
#
# 4. How many Literature Nobel award winners have a PhD (aka Doctorate of Philosophy) (you may check if they have a doctoral advisor)?
#
# 5. Are there books from Litarature Nobel Award winners which are not present in the Vatican Library? (if so, who is the author with more books not in the Vatical Library)?

# %% [markdown]
# ## 1. Identify the BGP for obtaining the nobel laureates and the nominees with their relevant attributes

# %% [markdown]
# First, I take some ten casual Italian Authors.

# %%
queryString = """
select distinct * where {
    # ?p wdt:P27 wd:Q38 .
    # ?p wdt:P106/wdt:P279* wd:Q36180 .
    
    # ?p <http://schema.org/name> ?name .
} limit 10
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/entity/Q61981709'), ('name', 'Francesco Lo Coco')]
# [('p', 'http://www.wikidata.org/entity/Q16185271'), ('name', 'Antonello Bonci')]
# [('p', 'http://www.wikidata.org/entity/Q43094174'), ('name', 'Cecilia Guariglia')]
# [('p', 'http://www.wikidata.org/entity/Q59528334'), ('name', 'Mauro Mancia')]
# [('p', 'http://www.wikidata.org/entity/Q48362107'), ('name', 'Fabrizio Doricchi')]
# [('p', 'http://www.wikidata.org/entity/Q104212291'), ('name', 'Manuela Musco')]
# [('p', 'http://www.wikidata.org/entity/Q102047173'), ('name', 'Davide Del Popolo Riolo')]
# [('p', 'http://www.wikidata.org/entity/Q90217125'), ('name', 'Giovanna Tosato')]
# [('p', 'http://www.wikidata.org/entity/Q96185295'), ('name', 'Enrica Petrini')]
# [('p', 'http://www.wikidata.org/entity/Q22582937'), ('name', 'Lorenzo Losa')]
# 10

# %% [markdown]
# Print all the properties releated to Italian authors

# %%
queryString = """
select distinct ?p ?pName where {
    # ?author wdt:P27 wd:Q38 ;
            wdt:P106/wdt:P279* wd:Q36180 ;
            # ?p ?o .
    
    # ?p <http://schema.org/name> ?pName .
}
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P9199'), ('pName', 'Protagonisti della storia delle scienze della mente ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2798'), ('pName', 'Loop ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3835'), ('pName', 'Mendeley person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1005'), ('pName', 'Portuguese National Library ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1006'), ('pName', 'Nationale Thesaurus voor Auteurs ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P101'), ('pName', 'field of work')]
# [('p', 'http://www.wikidata.org/prop/direct/P1015'), ('pName', 'NORAF ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P103'), ('pName', 'native language')]
# [('p', 'http://www.wikidata.org/prop/direct/P106'), ('pName', 'occupation')]
# [('p', 'http://www.wikidata.org/prop/direct/P1066'), ('pName', 'student of')]
# [('p', 'http://www.wikidata.org/prop/direct/P108'), ('pName', 'employer')]
# [('p', 'http://www.wikidata.org/prop/direct/P1153'), ('pName', 'Scopus author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1185'), ('pName', 'Rodovid ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1196'), ('pName', 'manner of death')]
# [('p', 'http://www.wikidata.org/prop/direct/P1207'), ('pName', 'NUKAT ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1233'), ('pName', 'Internet Speculative Fiction Database author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1280'), ('pName', 'CONOR.SI ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1340'), ('pName', 'eye color')]
# [('p', 'http://www.wikidata.org/prop/direct/P1343'), ('pName', 'described by source')]
# [('p', 'http://www.wikidata.org/prop/direct/P1412'), ('pName', 'languages spoken, written or signed')]
# [('p', 'http://www.wikidata.org/prop/direct/P1416'), ('pName', 'affiliation')]
# [('p', 'http://www.wikidata.org/prop/direct/P1607'), ('pName', 'Dialnet author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P166'), ('pName', 'award received')]
# [('p', 'http://www.wikidata.org/prop/direct/P18'), ('pName', 'image')]
# [('p', 'http://www.wikidata.org/prop/direct/P19'), ('pName', 'place of birth')]
# [('p', 'http://www.wikidata.org/prop/direct/P1960'), ('pName', 'Google Scholar author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P20'), ('pName', 'place of death')]
# [('p', 'http://www.wikidata.org/prop/direct/P2002'), ('pName', 'Twitter username')]
# [('p', 'http://www.wikidata.org/prop/direct/P2003'), ('pName', 'Instagram username')]
# [('p', 'http://www.wikidata.org/prop/direct/P2013'), ('pName', 'Facebook ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2037'), ('pName', 'GitHub username')]
# [('p', 'http://www.wikidata.org/prop/direct/P21'), ('pName', 'sex or gender')]
# [('p', 'http://www.wikidata.org/prop/direct/P213'), ('pName', 'ISNI')]
# [('p', 'http://www.wikidata.org/prop/direct/P214'), ('pName', 'VIAF ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P227'), ('pName', 'GND ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2381'), ('pName', 'Academic Tree ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P244'), ('pName', 'Library of Congress authority ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2671'), ('pName', 'Google Knowledge Graph ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P268'), ('pName', 'Bibliothèque nationale de France ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P269'), ('pName', 'IdRef ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P27'), ('pName', 'country of citizenship')]
# [('p', 'http://www.wikidata.org/prop/direct/P271'), ('pName', 'CiNii author ID (books)')]
# [('p', 'http://www.wikidata.org/prop/direct/P2847'), ('pName', 'Google+ ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2963'), ('pName', 'Goodreads author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3065'), ('pName', 'RERO ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('p', 'http://www.wikidata.org/prop/direct/P3267'), ('pName', 'Flickr user ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3602'), ('pName', 'candidacy in election')]
# [('p', 'http://www.wikidata.org/prop/direct/P373'), ('pName', 'Commons category')]
# [('p', 'http://www.wikidata.org/prop/direct/P3762'), ('pName', 'openMLOL author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3836'), ('pName', 'Pinterest username')]
# [('p', 'http://www.wikidata.org/prop/direct/P39'), ('pName', 'position held')]
# [('p', 'http://www.wikidata.org/prop/direct/P396'), ('pName', 'SBN author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3987'), ('pName', 'SHARE Catalogue author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P40'), ('pName', 'child')]
# [('p', 'http://www.wikidata.org/prop/direct/P4174'), ('pName', 'Wikimedia username')]
# [('p', 'http://www.wikidata.org/prop/direct/P4285'), ('pName', 'Theses.fr person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P4521'), ('pName', 'Radio Radicale person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P4619'), ('pName', 'National Library of Brazil ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P463'), ('pName', 'member of')]
# [('p', 'http://www.wikidata.org/prop/direct/P496'), ('pName', 'ORCID iD')]
# [('p', 'http://www.wikidata.org/prop/direct/P5008'), ('pName', 'on focus list of Wikimedia project')]
# [('p', 'http://www.wikidata.org/prop/direct/P5034'), ('pName', 'National Library of Korea ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P512'), ('pName', 'academic degree')]
# [('p', 'http://www.wikidata.org/prop/direct/P551'), ('pName', 'residence')]
# [('p', 'http://www.wikidata.org/prop/direct/P569'), ('pName', 'date of birth')]
# [('p', 'http://www.wikidata.org/prop/direct/P570'), ('pName', 'date of death')]
# [('p', 'http://www.wikidata.org/prop/direct/P5731'), ('pName', 'Angelicum ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5739'), ('pName', 'Pontificia Università della Santa Croce ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P646'), ('pName', 'Freebase ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6634'), ('pName', 'LinkedIn personal profile ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6886'), ('pName', 'writing language')]
# [('p', 'http://www.wikidata.org/prop/direct/P69'), ('pName', 'educated at')]
# [('p', 'http://www.wikidata.org/prop/direct/P691'), ('pName', 'NKCR AUT ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7293'), ('pName', 'PLWABN ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P734'), ('pName', 'family name')]
# [('p', 'http://www.wikidata.org/prop/direct/P735'), ('pName', 'given name')]
# [('p', 'http://www.wikidata.org/prop/direct/P742'), ('pName', 'pseudonym')]
# [('p', 'http://www.wikidata.org/prop/direct/P7699'), ('pName', 'National Library of Lithuania ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7859'), ('pName', 'WorldCat Identities ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P800'), ('pName', 'notable work')]
# [('p', 'http://www.wikidata.org/prop/direct/P8034'), ('pName', 'Vatican Library VcBA ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8179'), ('pName', 'Canadiana NCF ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8189'), ('pName', 'National Library of Israel J9U ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P856'), ('pName', 'official website')]
# [('p', 'http://www.wikidata.org/prop/direct/P8687'), ('pName', 'social media followers')]
# [('p', 'http://www.wikidata.org/prop/direct/P8795'), ('pName', 'General Diamond Catalogue ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P9037'), ('pName', 'BHCL UUID')]
# [('p', 'http://www.wikidata.org/prop/direct/P9179'), ('pName', 'Biblioteca Iglesia Nacional Española en Roma ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P9251'), ('pName', 'Cyprus University of Technology ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P950'), ('pName', 'Biblioteca Nacional de España ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P9534'), ('pName', 'Biblioteche della Custodia di Terra Santa a Gerusalemme ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P973'), ('pName', 'described at URL')]
# [('p', 'http://www.wikidata.org/prop/direct/P6715'), ('pName', 'SIUSA archive producer person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P9880'), ('pName', 'Festivaletteratura person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2038'), ('pName', 'ResearchGate profile ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P4012'), ('pName', 'Semantic Scholar author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6231'), ('pName', 'BDELIS ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P9634'), ('pName', 'AADFI member ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1017'), ('pName', 'Vatican Library ID (former scheme)')]
# [('p', 'http://www.wikidata.org/prop/direct/P1019'), ('pName', 'web feed URL')]
# [('p', 'http://www.wikidata.org/prop/direct/P102'), ('pName', 'member of political party')]
# [('p', 'http://www.wikidata.org/prop/direct/P1053'), ('pName', 'ResearcherID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1273'), ('pName', 'CANTIC ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1284'), ('pName', 'Munzinger person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1296'), ('pName', 'Gran Enciclopèdia Catalana ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1315'), ('pName', 'NLA Trove ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1341'), ('pName', 'Italian Chamber of Deputies dati ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1344'), ('pName', 'participant in')]
# [('p', 'http://www.wikidata.org/prop/direct/P135'), ('pName', 'movement')]
# [('p', 'http://www.wikidata.org/prop/direct/P1368'), ('pName', 'LNB ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1375'), ('pName', 'NSK ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1580'), ('pName', 'University of Barcelona authority ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1695'), ('pName', 'NLP ID (unique)')]
# [('p', 'http://www.wikidata.org/prop/direct/P1971'), ('pName', 'number of children')]
# [('p', 'http://www.wikidata.org/prop/direct/P1986'), ('pName', 'Biographical Dictionary of Italian People ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2163'), ('pName', 'FAST ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2174'), ('pName', 'Museum of Modern Art artist ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P22'), ('pName', 'father')]
# [('p', 'http://www.wikidata.org/prop/direct/P2397'), ('pName', 'YouTube channel ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2418'), ('pName', 'Structurae person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2435'), ('pName', 'PORT person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P245'), ('pName', 'Union List of Artist Names ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2522'), ('pName', 'victory')]
# [('p', 'http://www.wikidata.org/prop/direct/P26'), ('pName', 'spouse')]
# [('p', 'http://www.wikidata.org/prop/direct/P2604'), ('pName', 'Kinopoisk person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2732'), ('pName', 'Persée author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2924'), ('pName', 'Great Russian Encyclopedia Online ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3219'), ('pName', 'Encyclopædia Universalis ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3222'), ('pName', 'NE.se ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3348'), ('pName', 'National Library of Greece ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3365'), ('pName', 'Treccani ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3373'), ('pName', 'sibling')]
# [('p', 'http://www.wikidata.org/prop/direct/P3430'), ('pName', 'SNAC ARK ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P345'), ('pName', 'IMDb ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P349'), ('pName', 'National Diet Library ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3630'), ('pName', 'Babelio author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3935'), ('pName', 'Chamber of Deputies of Italy storia ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P409'), ('pName', 'Libraries Australia ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P4223'), ('pName', "Treccani's Enciclopedia Italiana ID")]
# [('p', 'http://www.wikidata.org/prop/direct/P4342'), ('pName', 'Store norske leksikon ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P4432'), ('pName', 'AKL Online artist ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P4663'), ('pName', 'DACS ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5019'), ('pName', 'Brockhaus Enzyklopädie online ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P509'), ('pName', 'cause of death')]
# [('p', 'http://www.wikidata.org/prop/direct/P5508'), ('pName', 'archINFORM person or group ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6275'), ('pName', 'copyright representative')]
# [('p', 'http://www.wikidata.org/prop/direct/P648'), ('pName', 'Open Library ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P650'), ('pName', 'RKDartists ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6578'), ('pName', 'MutualArt artist ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6656'), ('pName', 'BHCL ID (former scheme)')]
# [('p', 'http://www.wikidata.org/prop/direct/P6698'), ('pName', 'Japan Search name ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6706'), ('pName', 'De Agostini ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6821'), ('pName', 'Uppsala University Alvin ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6844'), ('pName', 'abART person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P723'), ('pName', 'Digitale Bibliotheek voor de Nederlandse Letteren author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7369'), ('pName', 'National Library of Chile ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7444'), ('pName', 'Rijksmuseum Research Library authority ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7666'), ('pName', 'Visuotinė lietuvių enciklopedija ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7763'), ('pName', 'copyright status as a creator')]
# [('p', 'http://www.wikidata.org/prop/direct/P7796'), ('pName', 'BeWeb person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7865'), ('pName', 'CoBiS author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7902'), ('pName', 'Deutsche Biographie (GND) ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8210'), ('pName', 'LombardiaBeniCulturali artwork author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8406'), ('pName', 'Grove Art Online ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P
ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P4611'), ('pName', 'LACMA ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P9511'), ('pName', 'am.hayazg.info ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3269'), ('pName', 'Fotografen.nl ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2409'), ('pName', 'CiNii article ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P9600'), ('pName', 'oral history at')]
# [('p', 'http://www.wikidata.org/prop/direct/P3502'), ('pName', 'Ameblo username')]
# [('p', 'http://www.wikidata.org/prop/direct/P4514'), ('pName', 'Africultures person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P9694'), ('pName', 'VK artist ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2283'), ('pName', 'uses')]
# [('p', 'http://www.wikidata.org/prop/direct/P1983'), ('pName', 'Anime News Network company ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2804'), ('pName', 'World Sailing member ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3332'), ('pName', 'ACM Digital Library citation ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6553'), ('pName', 'personal pronoun')]
# [('p', 'http://www.wikidata.org/prop/direct/P6228'), ('pName', 'RegiowikiAT ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1080'), ('pName', 'from narrative universe')]
# [('p', 'http://www.wikidata.org/prop/direct/P4991'), ('pName', 'Biographical Dictionary of Georgia ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8852'), ('pName', 'facial hair')]
# [('p', 'http://www.wikidata.org/prop/direct/P3869'), ('pName', 'IAFD female performer ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5267'), ('pName', 'YouPorn ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6290'), ('pName', 'Penthouse ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8767'), ('pName', 'EGAFD ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6146'), ('pName', 'The Hendon Mob ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P608'), ('pName', 'exhibition history')]
# [('p', 'http://www.wikidata.org/prop/direct/P88'), ('pName', 'commissioned by')]
# [('p', 'http://www.wikidata.org/prop/direct/P4206'), ('pName', 'FOIH person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6226'), ('pName', 'ARLLFB member ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P4175'), ('pName', 'Patreon ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2941'), ('pName', "Munk's Roll ID")]
# [('p', 'http://www.wikidata.org/prop/direct/P5291'), ('pName', 'Taratata artist ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8022'), ('pName', 'RFI Musique artist ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5797'), ('pName', 'Twitch channel ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3814'), ('pName', 'BoF person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P9538'), ('pName', 'music austria ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P598'), ('pName', 'commander of (DEPRECATED)')]
# [('p', 'http://www.wikidata.org/prop/direct/P1543'), ('pName', 'monogram')]
# [('p', 'http://www.wikidata.org/prop/direct/P2950'), ('pName', 'Nomisma ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8408'), ('pName', 'KBpedia ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P212'), ('pName', 'ISBN-13')]
# [('p', 'http://www.wikidata.org/prop/direct/P823'), ('pName', 'speaker')]
# [('p', 'http://www.wikidata.org/prop/direct/P6037'), ('pName', 'ProsopoMaths ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1260'), ('pName', 'Swedish Open Cultural Heritage URI')]
# [('p', 'http://www.wikidata.org/prop/direct/P5261'), ('pName', 'Les Enfoirés participant ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6342'), ('pName', 'Dictionnaire des Wallons ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P553'), ('pName', 'website account on')]
# [('p', 'http://www.wikidata.org/prop/direct/P3404'), ('pName', 'The Vogue List ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3111'), ('pName', 'FEI person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7176'), ('pName', 'XING profile ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5654'), ('pName', 'France Musique person ID')]
# 1397

# %% [markdown]
# Search for winner of nominees properites.

# %%
queryString = """
select distinct ?p ?pName where {
    # ?author wdt:P27 wd:Q38 ;
            wdt:P106/wdt:P279* wd:Q36180 ;
            # ?p ?o .
    
    # ?p <http://schema.org/name> ?pName .
    
    filter (regex(?pName, "win|nomin|rece", "i")).
}
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P166'), ('pName', 'award received')]
# [('p', 'http://www.wikidata.org/prop/direct/P1411'), ('pName', 'nominated for')]
# [('p', 'http://www.wikidata.org/prop/direct/P6150'), ('pName', 'Academy Awards Database nominee ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3360'), ('pName', 'Nobel Prize People Nomination ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P4286'), ('pName', 'Nominis saint ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5645'), ('pName', 'Académie française award winner ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7184'), ('pName', 'Awards & Winners artist ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5719'), ('pName', 'National Medal of Arts winner ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner')]
# 9

# %% [markdown]
# And so I get the property *award received (**P166**)*, *winner (**P1346**)* and the property *nominated for (**P1411**)*. To get people who won a Nobel prize, first I need the code for Nobel Prize. I can get it looking for what entities the Nobel Prize for literature is instance or is subclass of.

# %%
queryString = """
select ?p ?award ?awardName where {
    values ?p { wdt:P31 wdt:P279 } .
    
    wd:Q37922 ?p ?award.
    
    # ?award <http://schema.org/name> ?awardName .
}
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('award', 'http://www.wikidata.org/entity/Q7191'), ('awardName', 'Nobel Prize')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('award', 'http://www.wikidata.org/entity/Q378427'), ('awardName', 'literary award')]
# 2

# %% [markdown]
# So I need to look for awards that are subclasses of *Nobel Prize (**Q7191**)*. Let's count people who has been nominated or winned a Nobel.

# %%
queryString = """
select ?p (count(distinct ?author) as ?numAuthors) where {
    values ?p { wdt:P1411 wdt:P1346 wdt:P166 } .

    # ?author wdt:P106/wdt:P279* wd:Q36180 ;
            # ?p ?award .
    # ?award wdt:P279 wd:Q7191 .
} group by ?p
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P166'), ('numAuthors', '901')]
# [('p', 'http://www.wikidata.org/prop/direct/P1411'), ('numAuthors', '2132')]
# 2

# %% [markdown]
# So the property winner is never connected to a Nobel Prize. From the author I can get only the nominations. I then try to get the properties for Nobel Prize to see if there is a property that connect it to winners.

# %%
queryString = """
select distinct ?p ?pName where {
    # ?award ?p ?o ;
            wdt:P279 wd:Q7191 .
    
    # ?p <http://schema.org/name> ?pName .
}
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P6291'), ('pName', 'advertises')]
# [('p', 'http://www.wikidata.org/prop/direct/P112'), ('pName', 'founded by')]
# [('p', 'http://www.wikidata.org/prop/direct/P1296'), ('pName', 'Gran Enciclopèdia Catalana ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner')]
# [('p', 'http://www.wikidata.org/prop/direct/P138'), ('pName', 'named after')]
# [('p', 'http://www.wikidata.org/prop/direct/P1417'), ('pName', 'Encyclopædia Britannica Online ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P155'), ('pName', 'follows')]
# [('p', 'http://www.wikidata.org/prop/direct/P1617'), ('pName', 'BBC Things ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P17'), ('pName', 'country')]
# [('p', 'http://www.wikidata.org/prop/direct/P1705'), ('pName', 'native label')]
# [('p', 'http://www.wikidata.org/prop/direct/P18'), ('pName', 'image')]
# [('p', 'http://www.wikidata.org/prop/direct/P2257'), ('pName', 'event interval')]
# [('p', 'http://www.wikidata.org/prop/direct/P227'), ('pName', 'GND ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2354'), ('pName', 'has list')]
# [('p', 'http://www.wikidata.org/prop/direct/P2572'), ('pName', 'hashtag')]
# [('p', 'http://www.wikidata.org/prop/direct/P2581'), ('pName', 'BabelNet ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P276'), ('pName', 'location')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('p', 'http://www.wikidata.org/prop/direct/P3219'), ('pName', 'Encyclopædia Universalis ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3222'), ('pName', 'NE.se ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3393'), ('pName', 'LittleSis organization ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3417'), ('pName', 'Quora topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3509'), ('pName', 'Dagens Nyheter topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3553'), ('pName', 'Zhihu topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3569'), ('pName', 'Cultureel Woordenboek ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P361'), ('pName', 'part of')]
# [('p', 'http://www.wikidata.org/prop/direct/P373'), ('pName', 'Commons category')]
# [('p', 'http://www.wikidata.org/prop/direct/P3827'), ('pName', 'JSTOR topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P4342'), ('pName', 'Store norske leksikon ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P444'), ('pName', 'review score')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part')]
# [('p', 'http://www.wikidata.org/prop/direct/P571'), ('pName', 'inception')]
# [('p', 'http://www.wikidata.org/prop/direct/P580'), ('pName', 'start time')]
# [('p', 'http://www.wikidata.org/prop/direct/P6081'), ('pName', 'RIA Novosti reference')]
# [('p', 'http://www.wikidata.org/prop/direct/P6363'), ('pName', 'WordLift URL')]
# [('p', 'http://www.wikidata.org/prop/direct/P646'), ('pName', 'Freebase ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7502'), ('pName', 'Golden ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7818'), ('pName', 'French Vikidia ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8309'), ('pName', 'Yle topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8408'), ('pName', 'KBpedia ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P856'), ('pName', 'official website')]
# [('p', 'http://www.wikidata.org/prop/direct/P910'), ('pName', "topic's main category")]
# [('p', 'http://www.wikidata.org/prop/direct/P9100'), ('pName', 'GitHub topic')]
# [('p', 'http://www.wikidata.org/prop/direct/P9318'), ('pName', 'Ávvir topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P935'), ('pName', 'Commons gallery')]
# [('p', 'http://www.wikidata.org/prop/direct/P9466'), ('pName', 'Gyldendals Teaterleksikon ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P9545'), ('pName', 'Encyclopedia of China Online Database ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P9629'), ('pName', 'Armeniapedia ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P989'), ('pName', 'spoken text audio')]
# [('p', 'http://www.wikidata.org/prop/direct/P1027'), ('pName', 'conferred by')]
# [('p', 'http://www.wikidata.org/prop/direct/P2425'), ('pName', 'service ribbon image')]
# [('p', 'http://www.wikidata.org/prop/direct/P2517'), ('pName', 'category for recipients of this award')]
# 53

# %% [markdown]
# So the property *winner (**P1346**)* connects the Nobel Prize to the authors. The BGP for the authors who winned or has been nominated for a Nobel Prize in Literature is:
#
# ```
# ?author ^wdt:P1346|wdt:P1411|wdt:P166 wd:Q37922 .
# ```
#
# The BGP for the winners is:
#
# ```
# ?author ^wdt:P1346|wdt:P166 wd:Q37922 .
# ```
#
# And for the nominations:
#
# ```
# ?author wdt:P1411 wd:Q37922 .
# ```
#
# An alternative BGP, that let differentiate between nomination and win could be:
#
# ```
# values ?p { wdt:P1411 wdt:P1346 wdt:P166 } .
# { ?author ?p wd:Q37922 . } union { wd:Q37922 ?p ?author } .
# ```
#
# Or combining ```wdt:P279``` in the path, for example in the BGP for the nomination:
#
# ```
# ?author wdt:P1411|wdt:P279 wd:Q7191 .
# ```
#
# For what concerns Nobel Prize in general, instead of ```wd:Q37922```, I need to use ```?award``` and then add the following BGP:
#
# ```
# ?award wdt:P279 wd:Q7191 .
# ```

# %% [markdown]
# The next two queries counts the total number of nobel laurates and nominees using the two different BGPs. The second one let me divide between winners and nominees.

# %%
queryString = """
select (count(distinct ?author) as ?numAuthors) where {
    # ?author ^wdt:P1346|wdt:P1411|wdt:P166 ?award .
    
    # ?award wdt:P279 wd:Q7191 .
}
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('numAuthors', '2946')]
# 1

# %%
queryString = """
select ?p (count(distinct ?author) as ?numAuthors) where {
    values ?p { wdt:P1411 wdt:P1346 wdt:P166 } .
    
    { ?author ?p ?award . } union { ?award ?p ?author } .
    
    # ?award wdt:P279 wd:Q7191 .
} group by ?p
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P166'), ('numAuthors', '958')]
# [('p', 'http://www.wikidata.org/prop/direct/P1346'), ('numAuthors', '178')]
# [('p', 'http://www.wikidata.org/prop/direct/P1411'), ('numAuthors', '2395')]
# 3

# %% [markdown]
# The total number of 2946 nobel laurates and nominees is lower than the total 3531 of the second query, because some authors both winned and has been nominated for the Nobel Prize.

# %% [markdown]
# I can also count the winner of a nobel price for each category.

# %%
queryString = """
select ?awardName (count(distinct ?author) as ?numAuthors) where {
    # ?author ^wdt:P1346|wdt:P166 ?award .
    
    # ?award wdt:P279 wd:Q7191 .
    
    # ?award <http://schema.org/name> ?awardName .
}
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('awardName', 'Nobel Peace Prize'), ('numAuthors', '134')]
# [('awardName', 'Prize in Economic Sciences in Memory of Alfred Nobel'), ('numAuthors', '86')]
# [('awardName', 'Nobel Prize in Physics'), ('numAuthors', '215')]
# [('awardName', 'Nobel Prize in Literature'), ('numAuthors', '118')]
# [('awardName', 'Nobel Prize in Chemistry'), ('numAuthors', '185')]
# [('awardName', 'Nobel Prize in Physiology or Medicine'), ('numAuthors', '222')]
# 6

# %% [markdown]
# For what concerns the attributes of the nominees, I can see all the properties connected to some nobel winner.

# %%
queryString = """
select distinct ?author ?authorName where {
    # ?author ^wdt:P1346|wdt:P166 ?award .
    
    # ?award wdt:P279 wd:Q7191 .
    # ?author <http://schema.org/name> ?authorName .
} limit 5
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('author', 'http://www.wikidata.org/entity/Q115448'), ('authorName', 'Daniel Bovet')]
# [('author', 'http://www.wikidata.org/entity/Q15900993'), ('authorName', 'Barry C. Barish')]
# [('author', 'http://www.wikidata.org/entity/Q106751'), ('authorName', 'Alan J. Heeger')]
# [('author', 'http://www.wikidata.org/entity/Q76766'), ('authorName', 'Gerd Binnig')]
# [('author', 'http://www.wikidata.org/entity/Q192708'), ('authorName', 'Robert Coleman Richardson')]
# 5

# %%
queryString = """
select ?author ?p ?pName ?o ?oName where {
    values ?author { wd:Q115448 wd:Q106751 }
    
    # ?author ?p ?o .
    
    optional { ?p <http://schema.org/name> ?pName } .
    optional { ?o <http://schema.org/name> ?oName } .
} order by ?author
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('author', 'http://www.wikidata.org/entity/Q106751'), ('p', 'http://www.wikidata.org/prop/direct/P101'), ('pName', 'field of work'), ('o', 'http://www.wikidata.org/entity/Q2329'), ('oName', 'chemistry')]
# [('author', 'http://www.wikidata.org/entity/Q106751'), ('p', 'http://www.wikidata.org/prop/direct/P101'), ('pName', 'field of work'), ('o', 'http://www.wikidata.org/entity/Q413'), ('oName', 'physics')]
# [('author', 'http://www.wikidata.org/entity/Q106751'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('pName', 'occupation'), ('o', 'http://www.wikidata.org/entity/Q1622272'), ('oName', 'university teacher')]
# [('author', 'http://www.wikidata.org/entity/Q106751'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('pName', 'occupation'), ('o', 'http://www.wikidata.org/entity/Q169470'), ('oName', 'physicist')]
# [('author', 'http://www.wikidata.org/entity/Q106751'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('pName', 'occupation'), ('o', 'http://www.wikidata.org/entity/Q593644'), ('oName', 'chemist')]
# [('author', 'http://www.wikidata.org/entity/Q106751'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('pName', 'occupation'), ('o', 'http://www.wikidata.org/entity/Q81096'), ('oName', 'engineer')]
# [('author', 'http://www.wikidata.org/entity/Q106751'), ('p', 'http://www.wikidata.org/prop/direct/P108'), ('pName', 'employer'), ('o', 'http://www.wikidata.org/entity/Q168515'), ('oName', 'University of Utah')]
# [('author', 'http://www.wikidata.org/entity/Q106751'), ('p', 'http://www.wikidata.org/prop/direct/P108'), ('pName', 'employer'), ('o', 'http://www.wikidata.org/entity/Q503473'), ('oName', 'University of Geneva')]
# [('author', 'http://www.wikidata.org/entity/Q106751'), ('p', 'http://www.wikidata.org/prop/direct/P108'), ('pName', 'employer'), ('o', 'http://www.wikidata.org/entity/Q263064'), ('oName', 'University of California, Santa Barbara')]
# [('author', 'http://www.wikidata.org/entity/Q106751'), ('p', 'http://www.wikidata.org/prop/direct/P108'), ('pName', 'employer'), ('o', 'http://www.wikidata.org/entity/Q49117'), ('oName', 'University of Pennsylvania')]
# [('author', 'http://www.wikidata.org/entity/Q106751'), ('p', 'http://www.wikidata.org/prop/direct/P166'), ('pName', 'award received'), ('o', 'http://www.wikidata.org/entity/Q628457'), ('oName', 'Balzan Prize')]
# [('author', 'http://www.wikidata.org/entity/Q106751'), ('p', 'http://www.wikidata.org/prop/direct/P166'), ('pName', 'award received'), ('o', 'http://www.wikidata.org/entity/Q1572080'), ('oName', 'Oliver E. Buckley Condensed Matter Prize')]
# [('author', 'http://www.wikidata.org/entity/Q106751'), ('p', 'http://www.wikidata.org/prop/direct/P166'), ('pName', 'award received'), ('o', 'http://www.wikidata.org/entity/Q6008420'), ('oName', 'Gold medal of the Spanish National Research Council')]
# [('author', 'http://www.wikidata.org/entity/Q106751'), ('p', 'http://www.wikidata.org/prop/direct/P166'), ('pName', 'award received'), ('o', 'http://www.wikidata.org/entity/Q1316544'), ('oName', 'Guggenheim Fellowship')]
# [('author', 'http://www.wikidata.org/entity/Q106751'), ('p', 'http://www.wikidata.org/prop/direct/P166'), ('pName', 'award received'), ('o', 'http://www.wikidata.org/entity/Q3332215'), ('oName', 'John Scott Medal')]
# [('author', 'http://www.wikidata.org/entity/Q106751'), ('p', 'http://www.wikidata.org/prop/direct/P166'), ('pName', 'award received'), ('o', 'http://www.wikidata.org/entity/Q41955909'), ('oName', 'Fellow of the American Physical Society')]
# [('author', 'http://www.wikidata.org/entity/Q106751'), ('p', 'http://www.wikidata.org/prop/direct/P166'), ('pName', 'award received'), ('o', 'http://www.wikidata.org/entity/Q44585'), ('oName', 'Nobel Prize in Chemistry')]
# [('author', 'http://www.wikidata.org/entity/Q106751'), ('p', 'http://www.wikidata.org/prop/direct/P166'), ('pName', 'award received'), ('o', 'http://www.wikidata.org/entity/Q34342994'), ('oName', 'honorary doctor of the University of Alicante')]
# [('author', 'http://www.wikidata.org/entity/Q106751'), ('p', 'http://www.wikidata.org/prop/direct/P184'), ('pName', 'doctoral advisor'), ('o', 'http://www.wikidata.org/entity/Q4707195'), ('oName', 'Alan M. Portis')]
# [('author', 'http://www.wikidata.org/entity/Q106751'), ('p', 'http://www.wikidata.org/prop/direct/P185'), ('pName', 'doctoral student'), ('o', 'http://www.wikidata.org/entity/Q16027706'), ('oName', 'Lee Kwang-hee')]
# [('author', 'http://www.wikidata.org/entity/Q106751'), ('p', 'http://www.wikidata.org/prop/direct/P185'), ('pName', 'doctoral student'), ('o', 'http://www.wikidata.org/entity/Q11180922'), ('oName', 'Yung Woo Park')]
# [('author', 'http://www.wikidata.org/entity/Q106751'), ('p', 'http://www.wikidata.org/prop/direct/P19'), ('pName', 'place of birth'), ('o', 'http://www.wikidata.org/entity/Q489255'), ('oName', 'Sioux City')]
# [('author', 'http://www.wikidata.org/entity/Q106751'), ('p', 'http://www.wikidata.org/prop/direct/P21'), ('pName', 'sex or gender'), ('o', 'http://www.wikidata.org/entity/Q6581097'), ('oName', 'male')]
# [('author', 'http://www.wikidata.org/entity/Q106751'), ('p', 'http://www.wikidata.org/prop/direct/P27'), ('pName', 'country of citizenship'), ('o', 'http://www.wikidata.org/entity/Q30'), ('oName', 'United States of America')]
# [('author', 'http://www.wikidata.org/entity/Q106751'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('o', 'http://www.wikidata.org/entity/Q5'), ('oName', 'human')]
# [('author', 'http://www.wikidata.org/entity/Q106751'), ('p', 'http://www.wikidata.org/prop/direct/P40'), ('pName', 'child'), ('o', 'http://www.wikidata.org/entity/Q5234879'), ('oName', 'David Heeger')]
# [('author', 'http://www.wikidata.org/entity/Q106751'), ('p', 'http://www.wikidata.org/prop/direct/P463'), ('pName', 'member of'), ('o', 'http://www.wikidata.org/entity/Q270794'), ('oName', 'National Academy of Sciences')]
# [('author', 'http://www.wikidata.org/entity/Q106751'), ('p', 'http://www.wikidata.org/prop/direct/P463'), ('pName', 'member of'), ('o', 'http://www.wikidata.org/entity/Q1493021'), ('oName', 'US National Academy of Engineering')]
# [('author', 'http://www.wikidata.org/entity/Q106751'), ('p', 'http://www.wikidata.org/prop/direct/P463'), ('pName', 'member of'), ('o', 'http://www.wikidata.org/entity/Q466113'), ('oName', 'American Physical Society')]
# [('author', 'http://www.wikidata.org/entity/Q106751'), ('p', 'http://www.wikidata.org/prop/direct/P463'), ('pName', 'member of'), ('o', 'http://www.wikidata.org/entity/Q530471'), ('oName', 'Chinese Academy of Sciences')]
# [('author', 'http://www.wikidata.org/entity/Q106751'), ('p', 'http://www.wikidata.org/prop/direct/P512'), ('pName', 'academic degree'), ('o', 'http://www.wikidata.org/entity/Q752297'), ('oName', 'Doctor of Philosophy')]
# [('author', 'http://www.wikidata.org/entity/Q106751'), ('p', 'http://www.wikidata.org/prop/direct/P551'), ('pName', 'residence'), ('o', 'http://www.wikidata.org/entity/Q489255'), ('oName', 'Sioux City')]
# [('author', 'http://www.wikidata.org/entity/Q106751'), ('p', 'http://www.wikidata.org/prop/direct/P551'), ('pName', 'residence'), ('o', 'http://www.wikidata.org/entity/Q43199'), ('oName', 'Omaha')]
# [('author', 'http://www.wikidata.org/entity/Q106751'), ('p', 'http://www.wikidata.org/prop/direct/P551'), ('pName', 'residence'), ('o', 'http://www.wikidata.org/entity/Q99'), ('oName', 'California')]
# [('author', 'http://www.wikidata.org/entity/Q106751'), ('p', 'http://www.wikidata.org/prop/direct/P551'), ('pName', 'residence'), ('o', 'http://www.wikidata.org/entity/Q1922723'), ('oName', 'Akron')]
# [('author', 'http://www.wikidata.org/entity/Q106751'), ('p', 'http://www.wikidata.org/prop/direct/P69'), ('pName', 'educated at'), ('o', 'http://www.wikidata.org/entity/Q7089410'), ('oName', 'Omaha Central High School')]
# [('author', 'http://www.wikidata.org/entity/Q106751'), ('p', 'http://www.wikidata.org/prop/direct/P69'), ('pName', 'educated at'), ('o', 'http://www.wikidata.org/entity/Q168756'), ('oName', 'University of California, Berkeley')]
# [('author', 'http://www.wikidata.org/entity/Q106751'), ('p', 'http://www.wikidata.org/prop/direct/P69'), ('pName', 'educated at'), ('o', 'http://www.wikidata.org/entity/Q1353679'), ('oName', 'University of Nebraska–Lincoln')]
# [('author', 'http://www.wikidata.org/entity/Q106751'), ('p', 'http://www.wikidata.org/prop/direct/P734'), ('pName', 'family name'), ('o', 'http://www.wikidata.org/entity/Q15948214'), ('oName', 'Heeger')]
# [('author', 'http://www.wikidata.org/entity/Q106751'), ('p', 'http://www.wikidata.org/prop/direct/P735'), ('pName', 'given name'), ('o', 'http://www.wikidata.org/entity/Q59955198'), ('oName', 'Alan Jay')]
# [('author', 'http://www.wikidata.org/entity/Q106751'), ('p', 'http://www.wikidata.org/prop/direct/P1207'), ('pName', 'NUKAT ID'), ('o', 'n2005124342')]
# [('author', 'http://www.wikidata.org/entity/Q106751'), ('p', 'http://www.wikidata.org/prop/direct/P1263'), ('pName', 'NNDB people ID'), ('o', '839/000100539')]
# [('author', 'http://www.wikidata.org/entity/Q106751'), ('p', 'http://www.wikidata.org/prop/direct/P1284'), ('pName', 'Munzinger person ID'), ('o', '00000023508')]
# [('author', 'http://www.wikidata.org/entity/Q106751'), ('p', 'http://www.wikidata.org/prop/direct/P1296'), ('pName', 'Gran Enciclopèdia Catalana ID'), ('o', '0259895')]
# [('author', 'http://www.wikidata.org/entity/Q106751'), ('p', 'http://www.wikidata.org/prop/direct/P1417'), ('pName', 'Encyclopædia Britannica Online ID'), ('o', 'biography/Alan-J-Heeger')]
# [('author', 'http://www.wikidata.org/entity/Q106751'), ('p', 'http://www.wikidata.org/prop/direct/P1556'), ('pName', 'zbMATH author ID'), ('o', 'heeger.a-j')]
# [('author', 'http://www.wikidata.org/entity/Q106751'), ('p', 'http://www.wikidata.org/prop/direct/P1559'), ('pName', 'name in native language'), ('o', 'Alan Heeger')]
# [('author', 'http://www.wikidata.org/entity/Q106751'), ('p', 'http://www.wikidata.org/prop/direct/P18'), ('pName', 'image'), ('o', 'http://commons.wikimedia.org/wiki/Special:FilePath/Heeger%2C%20Alan%20J.%20%281936%29.jpg')]
# [('author', 'http://www.wikidata.org/entity/Q106751'), ('p', 'http://www.wikidata.org/prop/direct/P2021'), ('pName', 'Erdős number'), ('o', '5')]
# [('author', 'http://www.wikidata.org/entity/Q106751'), ('p', 'http://www.wikidata.org/prop/direct/P213'), ('pName', 'ISNI'), ('o', '0000 0000 5711 0068')]
# [('author', 'http://www.wikidata.org/entity/Q106751'), ('p', 'http://www.wikidata.org/prop/direct/P214'), ('pName', 'VIAF ID'), ('o', '173533447')]
# [('author', 'http://www.wikidata.org/entity/Q106751'), ('p', 'http://www.wikidata.org/prop/direct/P214'), ('pName', 'VIAF ID'), ('o', '85832850')]
# [('author', 'http://www.wikidata.org/entity/Q106751'), ('p', 'http://www.wikidata.org/prop/direct/P2163'), ('pName', 'FAST ID'), ('o', '1925881')]
# [('author', 'http://www.wikidata.org/entity/Q106751'), ('p', 'http://www.wikidata.org/prop/direct/P227'), ('pName', 'GND ID'), ('o', '142804916')]
# [('author', 'http://www.wikidata.org/entity/Q106751'), ('p', 'http://www.wikidata.org/prop/direct/P2381'), ('pName', 'Academic Tree ID'), ('o', '52267')]
# [('author', 'http://www.wikidata.org/entity/Q106751'), ('p', 'http://www.wikidata.org/prop/direct/P244'), ('pName', 'Library of Congress authority ID'), ('o', 'n88047231')]
# [('author', 'http://www.wikidata.org/entity/Q106751'), ('p', 'http://www.wikidata.org/prop/direct/P2456'), ('pName', 'DBLP author ID'), ('o', '34/5057')]
# [('author', 'http://www.wikidata.org/entity/Q106751'), ('p', 'http://www.wikidata.org/prop/direct/P2888'), ('pName', 'exact match'), ('o', 'http://data.nobelprize.org/resource/laureate/729')]
# [('author', 'http://www.wikidata.org/entity/Q106751'), ('p', 'http://www.wikidata.org/prop/direct/P2924'), ('pName', 'Great Russian Encyclopedia Online ID'), ('o', '4665019')]
# [('author', 'http://www.wikidata.org/entity/Q106751'), ('p', 'http://www.wikidata.org/prop/direct/P3188'), ('pName', 'Nobel prize ID'), ('o', 'chemistry/laureates/2000/heeger')]
# [('author', 'http://www.wikidata.org/entity/Q106751'), ('p', 'http://www.wikidata.org/prop/direct/P3430'), ('pName', 'SNAC ARK ID'), ('o', 'w6p9292h')]
# [('author', 'http://www.wikidata.org/entity/Q106751'), ('p', 'http://www.wikidata.org/prop/direct/P373'), ('pName', 'Commons category'), ('o', 'Alan J. Heeger')]
# [('author', 'http://www.wikidata.org/entity/Q106751'), ('p', 'http://www.wikidata.org/prop/direct/P3987'), ('pName', 'SHARE Catalogue author ID'), ('o', '46911')]
# [('author', 'http://www.wikidata.org/entity/Q106751'), ('p', 'http://www.wikidata.org/prop/direct/P4342'), ('pName', 'Store norske leksikon ID'), ('o', 'Alan_J._Heeger')]
# [('author', 'http://www.wikidata.org/entity/Q106751'), ('p', 'http://www.wikidata.org/prop/direct/P5019'), ('pName', 'Brockhaus Enzyklopädie online ID'), ('o', 'heeger-alan-j')]
# [('author', 'http://www.wikidata.org/entity/Q106751'), ('p', 'http://www.wikidata.org/prop/direct/P5380'), ('pName', 'National Academy of Sciences member ID'), ('o', '29428')]
# [('author', 'http://www.wikidata.org/entity/Q106751'), ('p', 'http://www.wikidata.org/prop/direct/P5587'), ('pName', 'Libris-URI'), ('o', 'vs68bx3d46vx7kt')]
# [('author', 'http://www.wikidata.org/entity/Q106751'), ('p', 'http://www.wikidata.org/prop/direct/P569'), ('pName', 'date of birth'), ('o', '1936-01-22T00:00:00Z')]
# [('author', 'http://www.wikidata.org/entity/Q106751'), ('p', 'http://www.wikidata.org/prop/direct/P646'), ('pName', 'Freebase ID'), ('o', '/m/04f7xn')]
# [('author', 'http://www.wikidata.org/entity/Q106751'), ('p', 'http://www.wikidata.org/prop/direct/P6551'), ('pName', 'Physics History Network ID'), ('o', '11512039')]
# [('author', 'http://www.wikidata.org/entity/Q106751'), ('p', 'http://www.wikidata.org/prop/direct/P6594'), ('pName', 'Guggenheim fellows ID'), ('o', 'alan-j-heeger')]
# [('author', 'http://www.wikidata.org/entity/Q106751'), ('p', 'http://www.wikidata.org/prop/direct/P691'), ('pName', 'NKCR AUT ID'), ('o', 'xx0080743')]
# [('author', 'http://www.wikidata.org/entity/Q106751'), ('p', 'http://www.wikidata.org/prop/direct/P7666'), ('pName', 'Visuotinė lietuvių enciklopedija ID'), ('o', 'alan-heeger')]
# [('author', 'http://www.wikidata.org/entity/Q106751'), ('p', 'http://www.wikidata.org/prop/direct/P7859'), ('pName', 'WorldCat Identities ID'), ('o', 'lccn-n88047231')]
# [('author', 'http://www.wikidata.org/entity/Q106751'), ('p', 'http://www.wikidata.org/prop/direct/P7859'), ('pName', 'WorldCat Identities ID'), ('o', 'viaf-85832850')]
# [('author', 'http://www.wikidata.org/entity/Q106751'), ('p', 'http://www.wikidata.org/prop/direct/P8024'), ('pName', 'Nobel Laureate API ID'), ('o', '729')]
# [('author', 'http://www.wikidata.org/entity/Q106751'), ('p', 'http://www.wikidata.org/prop/direct/P906'), ('pName', 'SELIBR ID'), ('o', '231042')]
# [('author', 'http://www.wikidata.org/entity/Q106751'), ('p', 'http://www.wikidata.org/prop/direct/P9807'), ('pName', 'SNK ID'), ('o', '157408')]
# [('author', 'http://www.wikidata.org/entity/Q106751'), ('p', 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), ('o', 'http://wikiba.se/ontology#Item')]
# [('author', 'http://www.wikidata.org/entity/Q106751'), ('p', 'http://www.wikidata.org/prop/direct-normalized/P214'), ('o', 'http://viaf.org/viaf/173533447')]
# [('author', 'http://www.wikidata.org/entity/Q106751'), ('p', 'http://www.wikidata.org/prop/direct-normalized/P214'), ('o', 'http://viaf.org/viaf/85832850')]
# [('author', 'http://www.wikidata.org/entity/Q106751'), ('p', 'http://www.wikidata.org/prop/direct-normalized/P2163'), ('o', 'http://id.worldcat.org/fast/1925881')]
# [('author', 'http://www.wikidata.org/entity/Q106751'), ('p', 'http://www.wikidata.org/prop/direct-normalized/P227'), ('o', 'https://d-nb.info/gnd/142804916')]
# [('author', 'http://www.wikidata.org/entity/Q106751'), ('p', 'http://www.wikidata.org/prop/direct-normalized/P244'), ('o', 'https://id.loc.gov/authorities/names/n88047231')]
# [('author', 'http://www.wikidata.org/entity/Q106751'), ('p', 'http://www.wikidata.org/prop/direct-normalized/P2456'), ('o', 'https://dblp.org/pid/34/5057.rdf')]
# [('author', 'http://www.wikidata.org/entity/Q106751'), ('p', 'http://www.wikidata.org/prop/direct-normalized/P5587'), ('o', 'https://libris.kb.se/vs68bx3d46vx7kt')]
# [('author', 'http://www.wikidata.org/entity/Q106751'), ('p', 'http://www.wikidata.org/prop/direct-normalized/P646'), ('o', 'http://g.co/kg/m/04f7xn')]
# [('author', 'http://www.wikidata.org/entity/Q106751'), ('p', 'http://www.wikidata.org/prop/direct-normalized/P8024'), ('o', 'https://api.nobelprize.org/2.0/laureate/729')]
# [('author', 'http://www.wikidata.org/entity/Q106751'), ('p', 'http://www.wikidata.org/prop/direct-normalized/P906'), ('o', 'http://libris.kb.se/resource/auth/231042')]
# [('author', 'http://www.wikidata.org/entity/Q106751'), ('p', 'http://schema.org/name'), ('o', 'Alan J. Heeger')]
# [('author', 'http://www.wikidata.org/entity/Q115448'), ('p', 'http://www.wikidata.org/prop/direct/P101'), ('pName', 'field of work'), ('o', 'http://www.wikidata.org/entity/Q324089'), ('oName', 'histamine antagonist')]
# [('author', 'http://www.wikidata.org/entity/Q115448'), ('p', 'http://www.wikidata.org/prop/direct/P101'), ('pName', 'field of work'), ('o', 'http://www.wikidata.org/entity/Q411398'), ('oName', 'sulfonamide drug')]
# [('author', 'http://www.wikidata.org/entity/Q115448'), ('p', 'http://www.wikidata.org/prop/direct/P103'), ('pName', 'native language'), ('o', 'http://www.wikidata.org/entity/Q143'), ('oName', 'Esperanto')]
# [('author', 'http://www.wikidata.org/entity/Q115448'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('pName', 'occupation'), ('o', 'http://www.wikidata.org/entity/Q6337803'), ('oName', 'neuroscientist')]
# [('author', 'http://www.wikidata.org/entity/Q115448'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('pName', 'occupation'), ('o', 'http://www.wikidata.org/entity/Q1622272'), ('oName', 'university teacher')]
# [('author', 'http://www.wikidata.org/entity/Q115448'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('pName', 'occupation'), ('o', 'http://www.wikidata.org/entity/Q2919046'), ('oName', 'biochemist')]
# [('author', 'http://www.wikidata.org/entity/Q115448'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('pName', 'occupation'), ('o', 'http://www.wikidata.org/entity/Q39631'), ('oName', 'physician')]
# [('author', 'http://www.wikidata.org/entity/Q115448'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('pName', 'occupation'), ('o', 'http://www.wikidata.org/entity/Q864503'), ('oName', 'biologist')]
# [('author', 'http://www.wikidata.org/entity/Q115448'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('pName', 'occupation'), ('o', 'http://www.wikidata.org/entity/Q860918'), ('oName', 'Esperantist')]
# [('author', 'http://www.wikidata.org/entity/Q115448'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('pName', 'occupation'), ('o', 'http://www.wikidata.org/entity/Q105186'), ('oName', 'pharmacist')]
# [('author', 'http://www.wikidata.org/entity/Q115448'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('pName', 'occupation'), ('o', 'http://www.wikidata.org/entity/Q2114605'), ('oName', 'pharmacologist')]
# [('author', 'http://www.wikidata.org/entity/Q115448'), ('p', 'http://www.wikidata.org/prop/direct/P108'), ('pName', 'employer'), ('o', 'http://www.wikidata.org/entity/Q209344'), ('oName', 'Sapienza University of Rome')]
# [('author', 'http://www.wikidata.org/entity/Q115448'), ('p', 'http://www.wikidata.org/prop/direct/P108'), ('pName', 'employer'), ('o', 'http://www.wikidata.org/entity/Q391083'), ('oName', 'Pasteur Institute')]
# [('author', 'http://www.wikidata.org/entity/Q115448'), ('p', 'http://www.wikidata.org/prop/direct/P1196'), ('pName', 'manner of death'), ('o', 'http://www.wikidata.org/entity/Q3739104'), ('oName', 'natural causes')]
# [('author', 'http://www.wikidata.org/entity/Q115448'), ('p', 'http://www.wikidata.org/prop/direct/P1343'), ('pName', 'described by source'), ('o', 'http://www.wikidata.org/entity/Q17378135'), ('oName', 'Great Soviet Encyclopedia (1969–1978)')]
# [('author', 'http://www.wikidata.org/entity/Q115448'), ('p', 'http://www.wikidata.org/prop/direct/P1343'), ('pName', 'described by source'), ('o', 'http://www.wikidata.org/entity/Q67311526'), ('oName', 'Obalky knih.cz')]
# [('author', 'http://www.wikidata.org/entity/Q115448'), ('p', 'http://www.wikidata.org/prop/direct/P1343'), ('pName', 'described by source'), ('o', 'http://www.wikidata.org/entity/Q99413897'), ('oName', 'Medvik')]
# [('author', 'http://www.wikidata.org/entity/Q115448'), ('p', 'http://www.wikidata.org/prop/direct/P1411'), ('pName', 'nominated for'), ('o', 'http://www.wikidata.org/entity/Q80061'), ('oName', 'Nobel Prize in Physiology or Medicine')]
# [('author', 'http://www.wikidata.org/entity/Q115448'), ('p', 'http://www.wikidata.org/prop/direct/P1412'), ('pName', 'languages spoken, written or signed'), ('o', 'http://www.wikidata.org/entity/Q652'), ('oName', 'Italian')]
# [('author', 'http://www.wikidata.org/entity/Q115448'), ('p', 'http://www.wikidata.org/prop/direct/P1412'), ('pName', 'languages spoken, written or signed'), ('o', 'http://www.wikidata.org/entity/Q143'), ('oName', 'Esperanto')]
# [('author', 'http://www.wikidata.org/entity/Q115448'), ('p', 'http://www.wikidata.org/prop/direct/P166'), ('pName', 'award received'), ('o', 'http://www.wikidata.org/entity/Q14906020'), ('oName', 'Foreign Member of the Royal Society')]
# [('author', 'http://www.wikidata.org/entity/Q115448'), ('p', 'http://www.wikidata.org/prop/direct/P166'), ('pName', 'award received'), ('o', 'http://www.wikidata.org/entity/Q80061'), ('oName', 'Nobel Prize in Physiology or Medicine')]
# [('author', 'http://www.wikidata.org/entity/Q115448'), ('p', 'http://www.wikidata.org/prop/direct/P19'), ('pName', 'place of birth'), ('o', 'http://www.wikidata.org/entity/Q628354'), ('oName', 'Fleurier')]
# [('author', 'http://www.wikidata.org/entity/Q115448'), ('p', 'http://www.wikidata.org/prop/direct/P20'), ('pName', 'place of death'), ('o', 'http://www.wikidata.org/entity/Q220'), ('oName', 'Rome')]
# [('author', 'http://www.wikidata.org/entity/Q115448'), ('p', 'http://www.wikidata.org/prop/direct/P21'), ('pName', 'sex or gender'), ('o', 'http://www.wikidata.org/entity/Q6581097'), ('oName', 'male')]
# [('author', 'http://www.wikidata.org/entity/Q115448'), ('p', 'http://www.wikidata.org/prop/direct/P22'), ('pName', 'father'), ('o', 'http://www.wikidata.org/entity/Q2566641'), ('oName', 'Pierre Bovet')]
# [('author', 'http://www.wikidata.org/entity/Q115448'), ('p', 'http://www.wikidata.org/prop/direct/P26'), ('pName', 'spouse'), ('o', 'http://www.wikidata.org/entity/Q15905238'), ('oName', 'Filomena Nitti')]
# [('author', 'http://www.wikidata.org/entity/Q115448'), ('p', 'http://www.wikidata.org/prop/direct/P27'), ('pName', 'country of citizenship'), ('o', 'http://www.wikidata.org/entity/Q38'), ('oName', 'Italy')]
# [('author', 'http://www.wikidata.org/entity/Q115448'), ('p', 'http://www.wikidata.org/prop/direct/P27'), ('pName', 'country of citizenship'), ('o', 'http://www.wikidata.org/entity/Q39'), ('oName', 'Switzerland')]
# [('author', 'http://www.wikidata.org/entity/Q115448'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('o', 'http://www.wikidata.org/entity/Q5'), ('oName', 'human')]
# [('author', 'http://www.wikidata.org/entity/Q115448'), ('p', 'http://www.wikidata.org/prop/direct/P39'), ('pName', 'position held'), ('o', 'http://www.wikidata.org/entity/Q1622272'), ('oName', 'university teacher')]
# [('author', 'http://www.wikidata.org/entity/Q115448'), ('p', 'http://www.wikidata.org/prop/direct/P463'), ('pName', 'member of'), ('o', 'http://www.wikidata.org/entity/Q123885'), ('oName', 'Royal Society')]
# [('author', 'http://www.wikidata.org/entity/Q115448'), ('p', 'http://www.wikidata.org/prop/direct/P463'), ('pName', 'member of'), ('o', 'http://www.wikidata.org/entity/Q188771'), ('oName', 'French Academy of Sciences')]
# [('author', 'http://www.wikidata.org/entity/Q115448'), ('p', 'http://www.wikidata.org/prop/direct/P463'), ('pName', 'member of'), ('o', 'http://www.wikidata.org/entity/Q337555'), ('oName', 'Académie Nationale de Médecine')]
# [('author', 'http://www.wikidata.org/entity/Q115448'), ('p', 'http://www.wikidata.org/prop/direct/P463'), ('pName', 'member of'), ('o', 'http://www.wikidata.org/entity/Q463303'), ('oName', 'American Academy of Arts and Sciences')]
# [('author', 'http://www.wikidata.org/entity/Q115448'), ('p', 'http://www.wikidata.org/prop/direct/P509'), ('pName', 'cause of death'), ('o', 'http://www.wikidata.org/entity/Q12078'), ('oName', 'cancer')]
# [('author', 'http://www.wikidata.org/entity/Q115448'), ('p', 'http://www.wikidata.org/prop/direct/P512'), ('pName', 'academic degree'), ('o', 'http://www.wikidata.org/entity/Q849697'), ('oName', 'doctorate')]
# [('author', 'http://www.wikidata.org/entity/Q115448'), ('p', 'http://www.wikidata.org/prop/direct/P551'), ('pName', 'residence'), ('o', 'http://www.wikidata.org/entity/Q38'), ('oName', 'Italy')]
# [('author', 'http://www.wikidata.org/entity/Q115448'), ('p', 'http://www.wikidata.org/prop/direct/P69'), ('pName', 'educated at'), ('o', 'http://www.wikidata.org/entity/Q503473'), ('oName', 'University of Geneva')]
# [('author', 'http://www.wikidata.org/entity/Q115448'), ('p', 'http://www.wikidata.org/prop/direct/P734'), ('pName', 'family name'), ('o', 'http://www.wikidata.org/entity/Q56537828'), ('oName', 'Bovet')]
# [('author', 'http://www.wikidata.org/entity/Q115448'), ('p', 'http://www.wikidata.org/prop/direct/P735'), ('pName', 'given name'), ('o', 'http://www.wikidata.org/entity/Q14516546'), ('oName', 'Daniel')]
# [('author', 'http://www.wikidata.org/entity/Q115448'), ('p', 'http://www.wikidata.org/prop/direct/P6231'), ('pName', 'BDELIS ID'), ('o', '82053')]
# [('author', 'http://www.wikidata.org/entity/Q115448'), ('p', 'http://www.wikidata.org/prop/direct/P5418'), ('pName', 'Pasteur Institute person ID'), ('o', 'bov0')]
# [('author', 'http://www.wikidata.org/entity/Q115448'), ('p', 'http://www.wikidata.org/prop/direct/P1006'), ('pName', 'Nationale Thesaurus voor Auteurs ID'), ('o', '06759297X')]
# [('author', 'http://www.wikidata.org/entity/Q115448'), ('p', 'http://www.wikidata.org/prop/direct/P1153'), ('pName', 'Scopus author ID'), ('o', '7003628926')]
# [('author', 'http://www.wikidata.org/entity/Q115448'), ('p', 'http://www.wikidata.org/prop/direct/P1207'), ('pName', 'NUKAT ID'), ('o', 'n2008046722')]
# [('author', 'http://www.wikidata.org/entity/Q115448'), ('p', 'http://www.wikidata.org/prop/direct/P1263'), ('pName', 'NNDB people ID'), ('o', '736/000129349')]
# [('author', 'http://www.wikidata.org/entity/Q115448'), ('p', 'http://www.wikidata.org/prop/direct/P1280'), ('pName', 'CONOR.SI ID'), ('o', '24185443')]
# [('author', 'http://www.wikidata.org/entity/Q115448'), ('p', 'http://www.wikidata.org/prop/direct/P1284'), ('pName', 'Munzinger person ID'), ('o', '00000008084')]
# [('author', 'http://www.wikidata.org/entity/Q115448'), ('p', 'http://www.wikidata.org/prop/direct/P1296'), ('pName', 'Gran Enciclopèdia Catalana ID'), ('o', '0011900')]
# [('author', 'http://www.wikidata.org/entity/Q115448'), ('p', 'http://www.wikidata.org/prop/direct/P1417'), ('pName', 'Encyclopædia Britannica Online ID'), ('o', 'biography/Daniel-Bovet')]
# [('author', 'http://www.wikidata.org/entity/Q115448'), ('p', 'http://www.wikidata.org/prop/direct/P1580'), ('pName', 'University of Barcelona authority ID'), ('o', 'a1137634')]
# [('author', 'http://www.wikidata.org/entity/Q115448'), ('p', 'http://www.wikidata.org/prop/direct/P18'), ('pName', 'image'), ('o', 'http://commons.wikimedia.org/wiki/Special:FilePath/Daniel%20Bovet%20nobel.jpg')]
# [('author', 'http://www.wikidata.org/entity/Q115448'), ('p', 'http://www.wikidata.org/prop/direct/P1986'), ('pName', 'Biographical Dictionary of Italian People ID'), ('o', 'daniel-bovet')]
# [('author', 'http://www.wikidata.org/entity/Q115448'), ('p', 'http://www.wikidata.org/prop/direct/P213'), ('pName', 'ISNI'), ('o', '0000 0001 0915 0281')]
# [('author', 'http://www.wikidata.org/entity/Q115448'), ('p', 'http://www.wikidata.org/prop/direct/P214'), ('pName', 'VIAF ID'), ('o', '73703016')]
# [('author', 'http://www.wikidata.org/entity/Q115448'), ('p', 'http://www.wikidata.org/prop/direct/P2163'), ('pName', 'FAST ID'), ('o', '272528')]
# [('author', 'http://www.wikidata.org/entity/Q115448'), ('p', 'http://www.wikidata.org/prop/direct/P227'), ('pName', 'GND ID'), ('o', '1019631007')]
# [('author', 'http://www.wikidata.org/entity/Q115448'), ('p', 'http://www.wikidata.org/prop/direct/P2381'), ('pName', 'Academic Tree ID'), ('o', '590')]
# [('author', 'http://www.wikidata.org/entity/Q115448'), ('p', 'http://www.wikidata.org/prop/direct/P2383'), ('pName', 'CTHS person ID'), ('o', '117200')]
# [('author', 'http://www.wikidata.org/entity/Q115448'), ('p', 'http://www.wikidata.org/prop/direct/P244'), ('pName', 'Library of Congress authority ID'), ('o', 'nr90012156')]
# [('author', 'http://www.wikidata.org/entity/Q115448'), ('p', 'http://www.wikidata.org/prop/direct/P268'), ('pName', 'Bibliothèque nationale de France ID'), ('o', '12113694c')]
# [('author', 'http://www.wikidata.org/entity/Q115448'), ('p', 'http://www.wikidata.org/prop/direct/P269'), ('pName', 'IdRef ID'), ('o', '029529735')]
# [('author', 'http://www.wikidata.org/entity/Q115448'), ('p', 'http://www.wikidata.org/prop/direct/P2888'), ('pName', 'exact match'), ('o', 'http://data.nobelprize.org/resource/laureate/363')]
# [('author', 'http://www.wikidata.org/entity/Q115448'), ('p', 'http://www.wikidata.org/prop/direct/P2924'), ('pName', 'Great Russian Encyclopedia Online ID'), ('o', '1871278')]
# [('author', 'http://www.wikidata.org/entity/Q115448'), ('p', 'http://www.wikidata.org/prop/direct/P3188'), ('pName', 'Nobel prize ID'), ('o', 'medicine/laureates/1957/bovet')]
# [('author', 'http://www.wikidata.org/entity/Q115448'), ('p', 'http://www.wikidata.org/prop/direct/P3219'), ('pName', 'Encyclopædia Universalis ID'), ('o', 'daniel-bovet')]
# [('author', 'http://www.wikidata.org/entity/Q115448'), ('p', 'http://www.wikidata.org/prop/direct/P3222'), ('pName', 'NE.se ID'), ('o', 'daniel-bovet')]
# [('author', 'http://www.wikidata.org/entity/Q115448'), ('p', 'http://www.wikidata.org/prop/direct/P3360'), ('pName', 'Nobel Prize People Nomination ID'), ('o', '1251')]
# [('author', 'http://www.wikidata.org/entity/Q115448'), ('p', 'http://www.wikidata.org/prop/direct/P3430'), ('pName', 'SNAC ARK ID'), ('o', 'w66k039t')]
# [('author', 'http://www.wikidata.org/entity/Q115448'), ('p', 'http://www.wikidata.org/prop/direct/P373'), ('pName', 'Commons category'), ('o', 'Daniel Bovet')]
# [('author', 'http://www.wikidata.org/entity/Q115448'), ('p', 'http://www.wikidata.org/prop/direct/P3956'), ('pName', 'National Academy of Medicine (France) member ID'), ('o', '474')]
# [('author', 'http://www.wikidata.org/entity/Q115448'), ('p', 'http://www.wikidata.org/prop/direct/P396'), ('pName', 'SBN author ID'), ('o', 'IT\\ICCU\\BVEV\\008082')]
# [('author', 'http://www.wikidata.org/entity/Q115448'), ('p', 'http://www.wikidata.org/prop/direct/P3987'), ('pName', 'SHARE Catalogue author ID'), ('o', '287312')]
# [('author', 'http://www.wikidata.org/entity/Q115448'), ('p', 'http://www.wikidata.org/prop/direct/P4293'), ('pName', 'PM20 folder ID'), ('o', 'pe/002293')]
# [('author', 'http://www.wikidata.org/entity/Q115448'), ('p', 'http://www.wikidata.org/prop/direct/P5019'), ('pName', 'Brockhaus Enzyklopädie online ID'), ('o', 'bovet-daniel')]
# [('author', 'http://www.wikidata.org/entity/Q115448'), ('p', 'http://www.wikidata.org/prop/direct/P5375'), ('pName', 'BIU Santé person ID'), ('o', '2897')]
# [('author', 'http://www.wikidata.org/entity/Q115448'), ('p', 'http://www.wikidata.org/prop/direct/P569'), ('pName', 'date of birth'), ('o', '1907-03-23T00:00:00Z')]
# [('author', 'http://www.wikidata.org/entity/Q115448'), ('p', 'http://www.wikidata.org/prop/direct/P570'), ('pName', 'date of death'), ('o', '1992-04-08T00:00:00Z')]
# [('author', 'http://www.wikidata.org/entity/Q115448'), ('p', 'http://www.wikidata.org/prop/direct/P646'), ('pName', 'Freebase ID'), ('o', '/m/04_5bc')]
# [('author', 'http://www.wikidata.org/entity/Q115448'), ('p', 'http://www.wikidata.org/prop/direct/P6706'), ('pName', 'De Agostini ID'), ('o', 'Bovet,+Daniel')]
# [('author', 'http://www.wikidata.org/entity/Q115448'), ('p', 'http://www.wikidata.org/prop/direct/P691'), ('pName', 'NKCR AUT ID'), ('o', 'nlk20000090543')]
# [('author', 'http://www.wikidata.org/entity/Q115448'), ('p', 'http://www.wikidata.org/prop/direct/P7666'), ('pName', 'Visuotinė lietuvių enciklopedija ID'), ('o', 'daniel-bovet')]
# [('author', 'http://www.wikidata.org/entity/Q115448'), ('p', 'http://www.wikidata.org/prop/direct/P7744'), ('pName', 'Mille Anni di Scienza in Italia ID'), ('o', 'bovet')]
# [('author', 'http://www.wikidata.org/entity/Q115448'), ('p', 'http://www.wikidata.org/prop/direct/P7859'), ('pName', 'WorldCat Identities ID'), ('o', 'lccn-nr90012156')]
# [('author', 'http://www.wikidata.org/entity/Q115448'), ('p', 'http://www.wikidata.org/prop/direct/P7902'), ('pName', 'Deutsche Biographie (GND) ID'), ('o', '1019631007')]
# [('author', 'http://www.wikidata.org/entity/Q115448'), ('p', 'http://www.wikidata.org/prop/direct/P7929'), ('pName', 'Roglo person ID'), ('o', 'p=daniel;n=bovet')]
# [('author', 'http://www.wikidata.org/entity/Q115448'), ('p', 'http://www.wikidata.org/prop/direct/P7982'), ('pName', 'Hrvatska enciklopedija ID'), ('o', '9071')]
# [('author', 'http://www.wikidata.org/entity/Q115448'), ('p', 'http://www.wikidata.org/prop/direct/P8024'), ('pName', 'Nobel Laureate API ID'), ('o', '363')]
# [('author', 'http://www.wikidata.org/entity/Q115448'), ('p', 'http://www.wikidata.org/prop/direct/P8034'), ('pName', 'Vatican Library VcBA ID'), ('o', '495/124773')]
# [('author', 'http://www.wikidata.org/entity/Q115448'), ('p', 'http://www.wikidata.org/prop/direct/P8947'), ('pName', 'Museo Galileo authority ID'), ('o', '189129')]
# [('author', 'http://www.wikidata.org/entity/Q115448'), ('p', 'http://www.wikidata.org/prop/direct/P902'), ('pName', 'HDS ID'), ('o', '014301')]
# [('author', 'http://www.wikidata.org/entity/Q115448'), ('p', 'http://www.wikidata.org/prop/direct/P8219'), ('pName', 'ASUT ID'), ('o', 'bovet-daniel')]
# [('author', 'http://www.wikidata.org/entity/Q115448'), ('p', 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), ('o', 'http://wikiba.se/ontology#Item')]
# [('author', 'http://www.wikidata.org/entity/Q115448'), ('p', 'http://www.wikidata.org/prop/direct-normalized/P1006'), ('o', 'http://data.bibliotheken.nl/id/thes/p06759297X')]
# [('author', 'http://www.wikidata.org/entity/Q115448'), ('p', 'http://www.wikidata.org/prop/direct-normalized/P214'), ('o', 'http://viaf.org/viaf/73703016')]
# [('author', 'http://www.wikidata.org/entity/Q115448'), ('p', 'http://www.wikidata.org/prop/direct-normalized/P2163'), ('o', 'http://id.worldcat.org/fast/272528')]
# [('author', 'http://www.wikidata.org/entity/Q115448'), ('p', 'http://www.wikidata.org/prop/direct-normalized/P227'), ('o', 'https://d-nb.info/gnd/1019631007')]
# [('author', 'http://www.wikidata.org/entity/Q115448'), ('p', 'http://www.wikidata.org/prop/direct-normalized/P244'), ('o', 'https://id.loc.gov/authorities/names/nr90012156')]
# [('author', 'http://www.wikidata.org/entity/Q115448'), ('p', 'http://www.wikidata.org/prop/direct-normalized/P268'), ('o', 'http://data.bnf.fr/ark:/12148/cb12113694c#about')]
# [('author', 'http://www.wikidata.org/entity/Q115448'), ('p', 'http://www.wikidata.org/prop/direct-normalized/P269'), ('o', 'http://www.idref.fr/029529735/id')]
# [('author', 'http://www.wikidata.org/entity/Q115448'), ('p', 'http://www.wikidata.org/prop/direct-normalized/P646'), ('o', 'http://g.co/kg/m/04_5bc')]
# [('author', 'http://www.wikidata.org/entity/Q115448'), ('p', 'http://www.wikidata.org/prop/direct-normalized/P8024'), ('o', 'https://api.nobelprize.org/2.0/laureate/363')]
# [('author', 'http://www.wikidata.org/entity/Q115448'), ('p', 'http://schema.org/name'), ('o', 'Daniel Bovet')]
# 194

# %% [markdown]
# The most relevant property releated to the nobel prize is probably the *Nobel prize ID (**P3188**)*, which has the form `{category}/laureates/{year}/{surname}`

# %% [markdown]
# I can so try to retrieve the year when the laureates won the nobel using regex.

# %%
queryString = """
select distinct ?author ?nobelID ?yearWin where {
    values ?author { wd:Q115448 wd:Q106751 }
    
    # ?author wdt:P3188 ?nobelID .
    
    bind (xsd:gYear(replace(?nobelID, "[a-zA-Z0-9]+/laureates/([0-9]+)/.*", "$1")) as ?yearWin)
} order by ?author
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('author', 'http://www.wikidata.org/entity/Q106751'), ('nobelID', 'chemistry/laureates/2000/heeger'), ('yearWin', '2000-01-01')]
# [('author', 'http://www.wikidata.org/entity/Q115448'), ('nobelID', 'medicine/laureates/1957/bovet'), ('yearWin', '1957-01-01')]
# 2

# %% [markdown]
# So the final BGP to obtain the year when a laureates won a nobel is:
#
# ```
# ?author wdt:P3188 ?nobelID .
# bind (xsd:gYear(replace(?nobelID, "[a-zA-Z0-9]+/laureates/([0-9]+)/.*", "$1")) as ?yearWin)
# ```

# %% [markdown]
# I can also verify if the selected property is always present or not

# %%
queryString = """
select ?totalNobels ?nobelsWithID where {
    {
        select ?country (count(distinct ?nobel) as ?totalNobels) where {
            # ?nobel ^wdt:P1346|wdt:P166 ?award .
    
            # ?award wdt:P279 wd:Q7191 .
        }
    } .
    {
        select (count(distinct ?yearWin) as ?nobelsWithID) where {
            # ?nobel ^wdt:P1346|wdt:P166 ?award ;
                    wdt:P3188 ?nobelID .            
            # ?award wdt:P279 wd:Q7191 .
            
            bind (xsd:gYear(replace(?nobelID, "[a-zA-Z0-9]+/laureates/([0-9]+)/.*", "$1")) as ?yearWin)
        }
    }
}
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('totalNobels', '958'), ('nobelsWithID', '115')]
# 1

# %%
queryString = """
select ?countryName ?totalNobels ?nobelsWithID where {
    {
        select ?country (count(distinct ?nobel) as ?totalNobels) where {
            # ?nobel ^wdt:P1346|wdt:P166 ?award ;
                    wdt:P27 ?country .
    
            # ?award wdt:P279 wd:Q7191 .
        }
    } .
    {
        select ?country (count(distinct ?yearWin) as ?nobelsWithID) where {
            # ?nobel ^wdt:P1346|wdt:P166 ?award ;
                    wdt:P3188 ?nobelID ;
                    wdt:P27 ?country .
            
            # ?award wdt:P279 wd:Q7191 .
            
            bind (xsd:gYear(replace(?nobelID, "[a-zA-Z0-9]+/laureates/([0-9]+)/.*", "$1")) as ?yearWin)
        }
    }
    
    # ?country <http://schema.org/name> ?countryName .
} order by ?countryName
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('countryName', 'Albania'), ('totalNobels', '1'), ('nobelsWithID', '1')]
# [('countryName', 'Argentina'), ('totalNobels', '5'), ('nobelsWithID', '5')]
# [('countryName', 'Australia'), ('totalNobels', '12'), ('nobelsWithID', '10')]
# [('countryName', 'Austria'), ('totalNobels', '18'), ('nobelsWithID', '12')]
# [('countryName', 'Austria-Hungary'), ('totalNobels', '10'), ('nobelsWithID', '8')]
# [('countryName', 'Austrian Empire'), ('totalNobels', '1'), ('nobelsWithID', '1')]
# [('countryName', 'Azerbaijan Democratic Republic'), ('totalNobels', '1'), ('nobelsWithID', '1')]
# [('countryName', 'Baltic Germans'), ('totalNobels', '1'), ('nobelsWithID', '1')]
# [('countryName', 'Bangladesh'), ('totalNobels', '1'), ('nobelsWithID', '1')]
# [('countryName', 'Belarus'), ('totalNobels', '1'), ('nobelsWithID', '1')]
# [('countryName', 'Belgium'), ('totalNobels', '10'), ('nobelsWithID', '9')]
# [('countryName', 'Bizone'), ('totalNobels', '1'), ('nobelsWithID', '0')]
# [('countryName', 'Brazil'), ('totalNobels', '1'), ('nobelsWithID', '1')]
# [('countryName', 'British Empire'), ('totalNobels', '1'), ('nobelsWithID', '1')]
# [('countryName', 'British India'), ('totalNobels', '3'), ('nobelsWithID', '2')]
# [('countryName', 'Bulgaria'), ('totalNobels', '1'), ('nobelsWithID', '1')]
# [('countryName', 'Canada'), ('totalNobels', '25'), ('nobelsWithID', '18')]
# [('countryName', 'Chile'), ('totalNobels', '2'), ('nobelsWithID', '2')]
# [('countryName', 'Cisleithania'), ('totalNobels', '4'), ('nobelsWithID', '3')]
# [('countryName', 'Colombia'), ('totalNobels', '2'), ('nobelsWithID', '2')]
# [('countryName', 'Costa Rica'), ('totalNobels', '1'), ('nobelsWithID', '1')]
# [('countryName', 'Cyprus'), ('totalNobels', '1'), ('nobelsWithID', '0')]
# [('countryName', 'Czechoslovakia'), ('totalNobels', '5'), ('nobelsWithID', '4')]
# [('countryName', 'Denmark'), ('totalNobels', '14'), ('nobelsWithID', '10')]
# [('countryName', 'Dominion of India'), ('totalNobels', '1'), ('nobelsWithID', '1')]
# [('countryName', 'East Timor'), ('totalNobels', '2'), ('nobelsWithID', '1')]
# [('countryName', 'Egypt'), ('totalNobels', '4'), ('nobelsWithID', '3')]
# [('countryName', 'Finland'), ('totalNobels', '5'), ('nobelsWithID', '4')]
# [('countryName', 'France'), ('totalNobels', '70'), ('nobelsWithID', '45')]
# [('countryName', 'Free City of Danzig'), ('totalNobels', '1'), ('nobelsWithID', '1')]
# [('countryName', 'German Confederation'), ('totalNobels', '1'), ('nobelsWithID', '1')]
# [('countryName', 'German Democratic Republic'), ('totalNobels', '1'), ('nobelsWithID', '0')]
# [('countryName', 'German Empire'), ('totalNobels', '24'), ('nobelsWithID', '16')]
# [('countryName', 'German Reich'), ('totalNobels', '10'), ('nobelsWithID', '8')]
# [('countryName', 'Germany'), ('totalNobels', '74'), ('nobelsWithID', '46')]
# [('countryName', 'Ghana'), ('totalNobels', '1'), ('nobelsWithID', '1')]
# [('countryName', 'Greece'), ('totalNobels', '2'), ('nobelsWithID', '2')]
# [('countryName', 'Guatemala'), ('totalNobels', '2'), ('nobelsWithID', '2')]
# [('countryName', 'Hungary'), ('totalNobels', '11'), ('nobelsWithID', '9')]
# [('countryName', 'Iceland'), ('totalNobels', '1'), ('nobelsWithID', '1')]
# [('countryName', 'India'), ('totalNobels', '4'), ('nobelsWithID', '2')]
# [('countryName', 'Iran'), ('totalNobels', '1'), ('nobelsWithID', '1')]
# [('countryName', 'Iraq'), ('totalNobels', '1'), ('nobelsWithID', '0')]
# [('countryName', 'Ireland'), ('totalNobels', '1'), ('nobelsWithID', '1')]
# [('countryName', 'Ireland'), ('totalNobels', '8'), ('nobelsWithID', '6')]
# [('countryName', 'Irish Free State'), ('totalNobels', '1'), ('nobelsWithID', '1')]
# [('countryName', 'Israel'), ('totalNobels', '13'), ('nobelsWithID', '8')]
# [('countryName', 'Italy'), ('totalNobels', '13'), ('nobelsWithID', '9')]
# [('countryName', 'Japan'), ('totalNobels', '28'), ('nobelsWithID', '17')]
# [('countryName', 'Jordan'), ('totalNobels', '1'), ('nobelsWithID', '1')]
# [('countryName', 'Kenya'), ('totalNobels', '1'), ('nobelsWithID', '1')]
# [('countryName', 'Kenya Colony'), ('totalNobels', '1'), ('nobelsWithID', '1')]
# [('countryName', 'Khedivate of Egypt'), ('totalNobels', '1'), ('nobelsWithID', '1')]
# [('countryName', 'Kingdom of Egypt'), ('totalNobels', '1'), ('nobelsWithID', '1')]
# [('countryName', 'Kingdom of Hungary'), ('totalNobels', '1'), ('nobelsWithID', '0')]
# [('countryName', 'Kingdom of Italy'), ('totalNobels', '16'), ('nobelsWithID', '10')]
# [('countryName', 'Kingdom of Prussia'), ('totalNobels', '3'), ('nobelsWithID', '3')]
# [('countryName', 'Kingdom of Yugoslavia'), ('totalNobels', '2'), ('nobelsWithID', '2')]
# [('countryName', 'Kingdom of the Netherlands'), ('totalNobels', '21'), ('nobelsWithID', '13')]
# [('countryName', 'Liberia'), ('totalNobels', '2'), ('nobelsWithID', '1')]
# [('countryName', 'Lithuania'), ('totalNobels', '1'), ('nobelsWithID', '1')]
# [('countryName', 'Mandatory Palestine'), ('totalNobels', '1'), ('nobelsWithID', '1')]
# [('countryName', 'Mauritius'), ('totalNobels', '1'), ('nobelsWithID', '1')]
# [('countryName', 'Mexico'), ('totalNobels', '3'), ('nobelsWithID', '3')]
# [('countryName', 'Myanmar'), ('totalNobels', '1'), ('nobelsWithID', '1')]
# [('countryName', 'Nazi Germany'), ('totalNobels', '15'), ('nobelsWithID', '10')]
# [('countryName', 'New Zealand'), ('totalNobels', '3'), ('nobelsWithID', '3')]
# [('countryName', 'Nigeria'), ('totalNobels', '1'), ('nobelsWithID', '1')]
# [('countryName', 'Northern Ireland'), ('totalNobels', '1'), ('nobelsWithID', '1')]
# [('countryName', 'Norway'), ('totalNobels', '14'), ('nobelsWithID', '8')]
# [('countryName', 'Ottoman Empire'), ('totalNobels', '1'), ('nobelsWithID', '1')]
# [('countryName', 'Pakistan'), ('totalNobels', '2'), ('nobelsWithID', '2')]
# [('countryName', 'Palestinian National Authority'), ('totalNobels', '1'), ('nobelsWithID', '1')]
# [('countryName', "People's Republic of China"), ('totalNobels', '6'), ('nobelsWithID', '5')]
# [('countryName', 'Peru'), ('totalNobels', '1'), ('nobelsWithID', '1')]
# [('countryName', 'Poland'), ('totalNobels', '18'), ('nobelsWithID', '14')]
# [('countryName', 'Portugal'), ('totalNobels', '2'), ('nobelsWithID', '2')]
# [('countryName', 'Prussia'), ('totalNobels', '2'), ('nobelsWithID', '1')]
# [('countryName', 'Republic of China 1912–1949'), ('totalNobels', '3'), ('nobelsWithID', '1')]
# [('countryName', 'Republic of Egypt (1953–1958)'), ('totalNobels', '1'), ('nobelsWithID', '1')]
# [('countryName', 'Romania'), ('totalNobels', '4'), ('nobelsWithID', '4')]
# [('countryName', 'Russia'), ('totalNobels', '8'), ('nobelsWithID', '6')]
# [('countryName', 'Russian Empire'), ('totalNobels', '21'), ('nobelsWithID', '13')]
# [('countryName', 'Russian Socialist Federative Soviet Republic'), ('totalNobels', '5'), ('nobelsWithID', '5')]
# [('countryName', 'Saint Lucia'), ('totalNobels', '2'), ('nobelsWithID', '1')]
# [('countryName', 'Second Polish Republic'), ('totalNobels', '2'), ('nobelsWithID', '2')]
# [('countryName', 'Slovenia'), ('totalNobels', '1'), ('nobelsWithID', '1')]
# [('countryName', 'Socialist Federal Republic of Yugoslavia'), ('totalNobels', '1'), ('nobelsWithID', '1')]
# [('countryName', 'South Africa'), ('totalNobels', '10'), ('nobelsWithID', '9')]
# [('countryName', 'South Korea'), ('totalNobels', '1'), ('nobelsWithID', '1')]
# [('countryName', 'Soviet Union'), ('totalNobels', '24'), ('nobelsWithID', '16')]
# [('countryName', 'Spain'), ('totalNobels', '8'), ('nobelsWithID', '7')]
# [('countryName', 'Spain'), ('totalNobels', '1'), ('nobelsWithID', '1')]
# [('countryName', 'Sultanate of Egypt'), ('totalNobels', '1'), ('nobelsWithID', '1')]
# [('countryName', 'Sweden'), ('totalNobels', '36'), ('nobelsWithID', '25')]
# [('countryName', 'Switzerland'), ('totalNobels', '30'), ('nobelsWithID', '21')]
# [('countryName', 'Taiwan'), ('totalNobels', '2'), ('nobelsWithID', '0')]
# [('countryName', 'Tibet'), ('totalNobels', '1'), ('nobelsWithID', '1')]
# [('countryName', 'Trinidad and Tobago'), ('totalNobels', '1'), ('nobelsWithID', '1')]
# [('countryName', 'Turkey'), ('totalNobels', '2'), ('nobelsWithID', '2')]
# [('countryName', 'United Arab Republic'), ('totalNobels', '1'), ('nobelsWithID', '1')]
# [('countryName', 'United Kingdom'), ('totalNobels', '122'), ('nobelsWithID', '63')]
# [('countryName', 'United Kingdom of Great Britain and Ireland'), ('totalNobels', '24'), ('nobelsWithID', '18')]
# [('countryName', 'United States of America'), ('totalNobels', '408'), ('nobelsWithID', '89')]
# [('countryName', 'Venezuela'), ('totalNobels', '1'), ('nobelsWithID', '1')]
# [('countryName', 'Vietnam'), ('totalNobels', '1'), ('nobelsWithID', '1')]
# [('countryName', 'Wales'), ('totalNobels', '1'), ('nobelsWithID', '0')]
# [('countryName', 'Weimar Republic'), ('totalNobels', '13'), ('nobelsWithID', '9')]
# [('countryName', 'West Germany'), ('totalNobels', '7'), ('nobelsWithID', '5')]
# [('countryName', 'Yemen'), ('totalNobels', '1'), ('nobelsWithID', '1')]
# 110

# %% [markdown]
# So, only in some cases I can retrieve the year when the prize is winned. But, in order to answer the next questions, this is the only way to obtain this property. From the second query, divided by country, we can also see that (except for USA), the nobel prizes for wich we cannot retrieve the year it is relatively well distributed, so I can use this subset of 115 nobel laureates as a good representation in order to compare countries.

# %% [markdown]
# ## 2. Get the number of Italian, French and Iranian winners and check which nation won more awards in the last twenty years.

# %% [markdown]
# First of all, I need the code for Italy, French and Iran. I can found them looking for the countries that are instances of *Sovereign state (**Q3624078**)*

# %%
queryString = """
select ?country ?countryName where {
    # ?country wdt:P31 wd:Q3624078 .

    # ?country <http://schema.org/name> ?countryName .
        
    filter regex(?countryName, "[Ii]tal|[Ff]ranc|[Ii]ran") .
}
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('country', 'http://www.wikidata.org/entity/Q142'), ('countryName', 'France')]
# [('country', 'http://www.wikidata.org/entity/Q38'), ('countryName', 'Italy')]
# [('country', 'http://www.wikidata.org/entity/Q794'), ('countryName', 'Iran')]
# 3

# %% [markdown]
# So I got *France (**Q142**)*, *Italy (**Q38**)* and *Iran (**Q794**)*. Now I can get some nobel laureates and their nationality.

# %%
queryString = """
select distinct ?author ?authorName ?countryName ?yearWin ?yearElapsed where {
    values ?country { wd:Q142 wd:Q38 wd:Q794 } .

    # ?author ^wdt:P1346|wdt:P166 ?award ;
            wdt:P3188 ?nobelID ;
            wdt:P27 ?country .
    
    # ?award wdt:P279 wd:Q7191 .
    
    bind (xsd:int(replace(?nobelID, "[a-zA-Z0-9]+/laureates/([0-9]+)/.*", "$1")) as ?yearWin) .
    bind (year(now()) - ?yearWin as ?yearElapsed) .
    
    # ?author <http://schema.org/name> ?authorName .
    # ?country <http://schema.org/name> ?countryName .
} limit 20
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('author', 'http://www.wikidata.org/entity/Q115448'), ('authorName', 'Daniel Bovet'), ('countryName', 'Italy'), ('yearWin', '1957'), ('yearElapsed', '65')]
# [('author', 'http://www.wikidata.org/entity/Q103598'), ('authorName', 'Luc Montagnier'), ('countryName', 'France'), ('yearWin', '2008'), ('yearElapsed', '14')]
# [('author', 'http://www.wikidata.org/entity/Q103844'), ('authorName', 'Françoise Barré-Sinoussi'), ('countryName', 'France'), ('yearWin', '2008'), ('yearElapsed', '14')]
# [('author', 'http://www.wikidata.org/entity/Q109553'), ('authorName', 'Renato Dulbecco'), ('countryName', 'Italy'), ('yearWin', '1975'), ('yearElapsed', '47')]
# [('author', 'http://www.wikidata.org/entity/Q17280087'), ('authorName', 'Emmanuelle Charpentier'), ('countryName', 'France')]
# [('author', 'http://www.wikidata.org/entity/Q244395'), ('authorName', 'Seán MacBride'), ('countryName', 'France'), ('yearWin', '1974'), ('yearElapsed', '48')]
# [('author', 'http://www.wikidata.org/entity/Q71023'), ('authorName', 'Alfred Kastler'), ('countryName', 'France'), ('yearWin', '1966'), ('yearElapsed', '56')]
# [('author', 'http://www.wikidata.org/entity/Q238731'), ('authorName', "Paul-Henri-Benjamin d'Estournelles de Constant"), ('countryName', 'France')]
# [('author', 'http://www.wikidata.org/entity/Q238731'), ('authorName', "Paul-Henri-Benjamin d'Estournelles de Constant"), ('countryName', 'France'), ('yearWin', '1909'), ('yearElapsed', '113')]
# [('author', 'http://www.wikidata.org/entity/Q3169751'), ('authorName', 'Jean-Pierre Sauvage'), ('countryName', 'France'), ('yearWin', '2016'), ('yearElapsed', '6')]
# [('author', 'http://www.wikidata.org/entity/Q173994'), ('authorName', 'Jean Tirole'), ('countryName', 'France')]
# [('author', 'http://www.wikidata.org/entity/Q34670'), ('authorName', 'Antonio carglass'), ('countryName', 'France'), ('yearWin', '1957'), ('yearElapsed', '65')]
# [('author', 'http://www.wikidata.org/entity/Q49325'), ('authorName', 'Albert Schweitzer'), ('countryName', 'France'), ('yearWin', '1952'), ('yearElapsed', '70')]
# [('author', 'http://www.wikidata.org/entity/Q186481'), ('authorName', 'Riccardo Giacconi'), ('countryName', 'Italy'), ('yearWin', '2002'), ('yearElapsed', '20')]
# [('author', 'http://www.wikidata.org/entity/Q187224'), ('authorName', 'Pierre-Gilles de Gennes'), ('countryName', 'France'), ('yearWin', '1991'), ('yearElapsed', '31')]
# [('author', 'http://www.wikidata.org/entity/Q214851'), ('authorName', 'Charles Richet'), ('countryName', 'France'), ('yearWin', '1913'), ('yearElapsed', '109')]
# [('author', 'http://www.wikidata.org/entity/Q129155'), ('authorName', 'Roger Martin du Gard'), ('countryName', 'France'), ('yearWin', '1937'), ('yearElapsed', '85')]
# [('author', 'http://www.wikidata.org/entity/Q222944'), ('authorName', 'Patrick Modiano'), ('countryName', 'France'), ('yearWin', '2014'), ('yearElapsed', '8')]
# [('author', 'http://www.wikidata.org/entity/Q153219'), ('authorName', 'Albert Fert'), ('countryName', 'France'), ('yearWin', '2007'), ('yearElapsed', '15')]
# [('author', 'http://www.wikidata.org/entity/Q133232'), ('authorName', 'Gabriel Lippmann'), ('countryName', 'France')]
# 20

# %% [markdown]
# And finally I count the number of Nobel laureates for the three countries

# %%
queryString = """
select ?countryName (count(distinct ?winner) as ?numWinners) where {
    values ?country { wd:Q142 wd:Q38 wd:Q794 } .

    # ?winner ^wdt:P1346|wdt:P166 ?award ;
            wdt:P27 ?country .
    
    # ?award wdt:P279 wd:Q7191 .
    
    # ?country <http://schema.org/name> ?countryName .
} group by ?countryName
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('countryName', 'Iran'), ('numWinners', '1')]
# [('countryName', 'France'), ('numWinners', '70')]
# [('countryName', 'Italy'), ('numWinners', '13')]
# 3

# %% [markdown]
# And the country that have the greates number of nobel laureates in the last 20 years is:

# %%
queryString = """
select ?country ?countryName (count(distinct ?winner) as ?numWinners) where {
    # ?winner ^wdt:P1346|wdt:P166 ?award ;
            wdt:P3188 ?nobelID ;
            wdt:P27 ?country .
    
    # ?award wdt:P279 wd:Q7191 .
    
    # ?country <http://schema.org/name> ?countryName .
    
    bind (xsd:int(replace(?nobelID, "[a-zA-Z0-9]+/laureates/([0-9]+)/.*", "$1")) as ?yearWin) .
    
    filter (year(now()) - ?yearWin <= "20"^^xsd:int)
} group by ?country ?countryName
order by desc(?numWinners)
limit 1
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('country', 'http://www.wikidata.org/entity/Q30'), ('countryName', 'United States of America'), ('numWinners', '77')]
# 1

# %% [markdown]
# USA is the country with the greatest number of laureates in the last 20 year. We also need to consider that USA was also the country with less laureates for which we can retrieve the year, so the comparison is made considering only 89 laureates for USA, instead of the total number of 408. However, the winner still USA, so taking a subset of the laureates didn't affected the result.

# %% [markdown]
# ## 3. Determine how many Literature nobel laureates have the following countries: Italy, Germany, France, Romania, Denmark, Iran, and China

# %% [markdown]
# First, I need to get the code for the countries.

# %%
queryString = """
select ?country ?countryName where {
    # ?country wdt:P31 wd:Q3624078 .

    # ?country <http://schema.org/name> ?countryName .
    
    filter regex(?countryName, "[Ii]tal|[Ff]ranc|[Ii]ran|[Gg]erman|[Rr]omania|[Dd]enmark|[Cc]hina")
}
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('country', 'http://www.wikidata.org/entity/Q142'), ('countryName', 'France')]
# [('country', 'http://www.wikidata.org/entity/Q148'), ('countryName', "People's Republic of China")]
# [('country', 'http://www.wikidata.org/entity/Q183'), ('countryName', 'Germany')]
# [('country', 'http://www.wikidata.org/entity/Q218'), ('countryName', 'Romania')]
# [('country', 'http://www.wikidata.org/entity/Q35'), ('countryName', 'Denmark')]
# [('country', 'http://www.wikidata.org/entity/Q38'), ('countryName', 'Italy')]
# [('country', 'http://www.wikidata.org/entity/Q7318'), ('countryName', 'Nazi Germany')]
# [('country', 'http://www.wikidata.org/entity/Q794'), ('countryName', 'Iran')]
# [('country', 'http://www.wikidata.org/entity/Q107312248'), ('countryName', 'Republic of China')]
# 9

# %% [markdown]
# So I got *France (**Q142**)*, *Italy (**Q38**)*, *Iran (**Q794**)*, *Germany (**Q183**)*, *Romania (**Q218**)*, *Denmark (**Q35**)*, *China (**Q148**)*. For what concern China, I use *People's Republic of China (PRC)*, because it is the real name of the China state (Republic of China is Taiwan). So I can retrieve the total number of laureates using the BGP for Nobel Laureates of the point 1.

# %%
queryString = """
select ?countryName (count(distinct ?author) as ?numLaureates) where {
    values ?country { wd:Q142 wd:Q38 wd:Q794 wd:Q183 wd:Q218 wd:Q35 wd:Q148 } .

    # ?author ^wdt:P1346|wdt:P166 wd:Q37922 ;
            wdt:P27 ?country .
        
    # ?country <http://schema.org/name> ?countryName .
} group by ?countryName
order by desc(?numLaureates)
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('countryName', 'France'), ('numLaureates', '17')]
# [('countryName', 'Germany'), ('numLaureates', '6')]
# [('countryName', 'Denmark'), ('numLaureates', '4')]
# [('countryName', 'Italy'), ('numLaureates', '3')]
# [('countryName', "People's Republic of China"), ('numLaureates', '2')]
# [('countryName', 'Romania'), ('numLaureates', '1')]
# 6

# %% [markdown]
# ## 4. How many Literature Nobel award winners have a PhD (aka Doctorate of Philosophy) (you may check if they have a doctoral advisor)?

# %% [markdown]
# I can find for doctoral advisors looking at the properties which are connected from any entity to the literature nobel winners, and looking for the property doctoral advisor.

# %%
queryString = """
select distinct ?p ?pName where {
    # ?author ^wdt:P1346|wdt:P166 wd:Q37922 .
    
    # ?author ?p ?o .
        
    # ?p <http://schema.org/name> ?pName .
    
    filter (regex(?pName, "doctor"))
}
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P184'), ('pName', 'doctoral advisor')]
# [('p', 'http://www.wikidata.org/prop/direct/P185'), ('pName', 'doctoral student')]
# [('p', 'http://www.wikidata.org/prop/direct/P5459'), ('pName', 'RHE doctor ID')]
# 3

# %% [markdown]
# So, a person has a PhD if there is a property *doctoral advisor (**P184**)* and *doctoral student (**P185**)* from the person to any entity. I can consider both paths (phd to its advisor, advisor to phd) The BGP is the following one:
#
# ```
# ?author ^wdt:P185|wdt:P184 ?o .
# ```
#
# And so, I can answer the question.

# %%
queryString = """
select count(distinct ?author) as ?numLaureatesWithPhD where {
    # ?author ^wdt:P1346|wdt:P166 wd:Q37922 ;
            ^wdt:P185|wdt:P184 ?o .
}
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('numLaureatesWithPhD', '2')]
# 1

# %% [markdown]
# The number of Literature Nobel laureates with a PhD is 2. We can also list this persons, which are:

# %%
queryString = """
select distinct ?author ?authorName where {
    # ?author ^wdt:P1346|wdt:P166 wd:Q37922 ;
            ^wdt:P185|wdt:P184 ?o .
    
    # ?author <http://schema.org/name> ?authorName .
}
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('author', 'http://www.wikidata.org/entity/Q33760'), ('authorName', 'Bertrand Russell')]
# [('author', 'http://www.wikidata.org/entity/Q47695'), ('authorName', 'Rudolf Christoph Eucken')]
# 2

# %% [markdown]
# Only, for curiosity and comparison, I can also count the total number of nobel laureates with a PhD.

# %%
queryString = """
select count(distinct ?author) as ?numLaureatesWithPhD where {
    # ?author ^wdt:P1346|wdt:P166 ?award ;
            ^wdt:P185|wdt:P184 ?o .
    
    # ?award wdt:P279 wd:Q7191 .
}
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('numLaureatesWithPhD', '428')]
# 1

# %% [markdown]
# That is about the 44% of total nobel laureates. I can finally also see which are the categories with the high number of laureates with a PhD.

# %%
queryString = """
select ?awardName count(distinct ?author) as ?numLaureatesWithPhD where {
    # ?author ^wdt:P1346|wdt:P166 ?award ;
            ^wdt:P185|wdt:P184 ?o .
    
    # ?award wdt:P279 wd:Q7191 .
    
    # ?award <http://schema.org/name> ?awardName .
} group by ?award ?awardName
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('awardName', 'Nobel Prize in Literature'), ('numLaureatesWithPhD', '2')]
# [('awardName', 'Nobel Peace Prize'), ('numLaureatesWithPhD', '8')]
# [('awardName', 'Nobel Prize in Physiology or Medicine'), ('numLaureatesWithPhD', '73')]
# [('awardName', 'Nobel Prize in Physics'), ('numLaureatesWithPhD', '153')]
# [('awardName', 'Nobel Prize in Chemistry'), ('numLaureatesWithPhD', '116')]
# [('awardName', 'Prize in Economic Sciences in Memory of Alfred Nobel'), ('numLaureatesWithPhD', '78')]
# 6

# %% [markdown]
# And I discover that Physics and Chemistry are the categories with the highest number of laureates with PhD.

# %% [markdown]
# ## 5. Are there books from Literature Nobel Award winners which are not present in the Vatican Library? (if so, who is the author with more books not in the Vatican Library)?

# %% [markdown]
# First of all, I need to find a property that link nobel winners, and more in general persons, with books

# %%
queryString = """
select distinct ?p ?pName where {
    # ?author ^wdt:P1346|wdt:P166 wd:Q37922 ;
            # ?p ?o .
        
    # ?p <http://schema.org/name> ?pName .
    
    filter (regex(?pName, "author", "i"))
}
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P1153'), ('pName', 'Scopus author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1233'), ('pName', 'Internet Speculative Fiction Database author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1556'), ('pName', 'zbMATH author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1580'), ('pName', 'University of Barcelona authority ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1607'), ('pName', 'Dialnet author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1670'), ('pName', 'Canadiana Authorities ID (former scheme)')]
# [('p', 'http://www.wikidata.org/prop/direct/P1899'), ('pName', 'LibriVox author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1938'), ('pName', 'Project Gutenberg author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1960'), ('pName', 'Google Scholar author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2188'), ('pName', 'BiblioNet author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P244'), ('pName', 'Library of Congress authority ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2607'), ('pName', 'BookBrainz author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P271'), ('pName', 'CiNii author ID (books)')]
# [('p', 'http://www.wikidata.org/prop/direct/P2732'), ('pName', 'Persée author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2734'), ('pName', 'Unz Review author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2963'), ('pName', 'Goodreads author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2966'), ('pName', 'National Library of Wales Authority ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3154'), ('pName', 'Runeberg author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3232'), ('pName', 'PhilPapers author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3280'), ('pName', 'BAnQ author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3630'), ('pName', 'Babelio author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3762'), ('pName', 'openMLOL author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3788'), ('pName', 'BNMM authority ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3846'), ('pName', 'DBC author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P396'), ('pName', 'SBN author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3987'), ('pName', 'SHARE Catalogue author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P4343'), ('pName', 'WBPLN author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P4629'), ('pName', 'Online Books Page author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P4862'), ('pName', 'Amazon author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5101'), ('pName', 'Swedish Literature Bank Author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5491'), ('pName', "BD Gest' author ID")]
# [('p', 'http://www.wikidata.org/prop/direct/P5570'), ('pName', 'NooSFere author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5695'), ('pName', 'Bibliopoche author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5705'), ('pName', 'Los Angeles Review of Books author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5859'), ('pName', 'Adelphi author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6173'), ('pName', 'Bitraga author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6300'), ('pName', 'Hymnary author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6745'), ('pName', 'Orlando author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6873'), ('pName', 'IntraText author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6984'), ('pName', 'Rupa Publications author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7031'), ('pName', 'Penguin India author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7208'), ('pName', 'Liber Liber author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P723'), ('pName', 'Digitale Bibliotheek voor de Nederlandse Letteren author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7311'), ('pName', 'Aozora Bunko author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7400'), ('pName', 'LibraryThing author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7433'), ('pName', 'FantLab author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7507'), ('pName', 'Ben Yehuda author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7865'), ('pName', 'CoBiS author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8234'), ('pName', 'LiederNet author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8833'), ('pName', 'Union Catalog of Armenian Libraries authority ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8947'), ('pName', 'Museo Galileo authority ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P9322'), ('pName', 'SVKKL authority ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P9337'), ('pName', "Keratsini-Drapetsona libraries' catalogue authority ID")]
# [('p', 'http://www.wikidata.org/prop/direct/P9459'), ('pName', 'Rekhta author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6329'), ('pName', 'Share-VDE author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7444'), ('pName', 'Rijksmuseum Research Library authority ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8287'), ('pName', 'Worlds Without End author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8547'), ('pName', 'BHF author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P9661'), ('pName', 'EBAF authority ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5408'), ('pName', 'Fantastic Fiction author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5643'), ('pName', 'RSL author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P4928'), ('pName', 'Ricorso author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P9053'), ('pName', 'Projecto Vercial author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1213'), ('pName', 'NLC authorities')]
# [('p', 'http://www.wikidata.org/prop/direct/P1473'), ('pName', 'BLPL author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P9029'), ('pName', 'Viceversa Letteratura author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5637'), ('pName', 'CNL author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6677'), ('pName', 'OpenEdition Books author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P9642'), ('pName', 'Olschki author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P9282'), ('pName', 'Catalogue of the Capitular Library of Verona author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P9507'), ('pName', 'NBM authority ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7331'), ('pName', 'Letteraturaitaliana.net author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8975'), ('pName', 'Manus Online author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8122'), ('pName', 'DLL Catalog author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P9536'), ('pName', 'SAIA authority ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3307'), ('pName', 'Galiciana authority ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6579'), ('pName', 'National Book Foundation author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5409'), ('pName', 'Île en île author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3964'), ('pName', 'BDCYL authority ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8689'), ('pName', 'ITHL author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7711'), ('pName', 'Joconde author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5394'), ('pName', 'Poets & Writers author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8160'), ('pName', 'Bibliotheca Augustana author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3133'), ('pName', 'NSZL name authority ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3973'), ('pName', 'PIM authority ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P50'), ('pName', 'author')]
# [('p', 'http://www.wikidata.org/prop/direct/P6441'), ('pName', 'Douban author ID')]
# 87

# %% [markdown]
# Probably the property *author (**P50**)* is the one I am looking for, I can check it verifying what are the entities connected with this property.

# %%
queryString = """
select distinct ?o ?oName ?subclass ?subclassName ?instance ?instanceName where {
    # ?author ^wdt:P1346|wdt:P166 wd:Q37922 .
    # ?o wdt:P50 ?author .
    
    optional {
        # ?o wdt:P279 ?subclass .
        # ?subclass <http://schema.org/name> ?subclassName .
    }
    
    optional {
        # ?o wdt:P31 ?instance .
        # ?instance <http://schema.org/name> ?instanceName .
    }
        
    # ?o <http://schema.org/name> ?oName .
} limit 20
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('o', 'http://www.wikidata.org/entity/Q7746252'), ('oName', 'The Last of the Light Brigade'), ('subclass', 'http://www.wikidata.org/entity/Q34743'), ('subclassName', 'Rudyard Kipling'), ('instance', 'http://www.wikidata.org/entity/Q5185279'), ('instanceName', 'poem')]
# [('o', 'http://www.wikidata.org/entity/Q19724435'), ('oName', 'Total Dictation'), ('subclass', 'http://www.wikidata.org/entity/Q1087138'), ('subclassName', 'dictation'), ('instance', 'http://www.wikidata.org/entity/Q2668072'), ('instanceName', 'collection')]
# [('o', 'http://www.wikidata.org/entity/Q19724435'), ('oName', 'Total Dictation'), ('subclass', 'http://www.wikidata.org/entity/Q1087138'), ('subclassName', 'dictation'), ('instance', 'http://www.wikidata.org/entity/Q11483816'), ('instanceName', 'annual event')]
# [('o', 'http://www.wikidata.org/entity/Q4657570'), ('oName', 'A Kind of Alaska'), ('instance', 'http://www.wikidata.org/entity/Q1194583'), ('instanceName', 'one-act play')]
# [('o', 'http://www.wikidata.org/entity/Q6485061'), ('oName', 'Landscape'), ('instance', 'http://www.wikidata.org/entity/Q1194583'), ('instanceName', 'one-act play')]
# [('o', 'http://www.wikidata.org/entity/Q17019158'), ('oName', 'Silence'), ('instance', 'http://www.wikidata.org/entity/Q1194583'), ('instanceName', 'one-act play')]
# [('o', 'http://www.wikidata.org/entity/Q2539975'), ('oName', 'The Birthday Party'), ('instance', 'http://www.wikidata.org/entity/Q25379'), ('instanceName', 'play')]
# [('o', 'http://www.wikidata.org/entity/Q4658572'), ('oName', 'A Night Out'), ('instance', 'http://www.wikidata.org/entity/Q25379'), ('instanceName', 'play')]
# [('o', 'http://www.wikidata.org/entity/Q1194169'), ('oName', 'The Caretaker'), ('instance', 'http://www.wikidata.org/entity/Q25379'), ('instanceName', 'play')]
# [('o', 'http://www.wikidata.org/entity/Q2866503'), ('oName', 'Ashes to Ashes'), ('instance', 'http://www.wikidata.org/entity/Q25379'), ('instanceName', 'play')]
# [('o', 'http://www.wikidata.org/entity/Q1453379'), ('oName', 'Celebration'), ('instance', 'http://www.wikidata.org/entity/Q25379'), ('instanceName', 'play')]
# [('o', 'http://www.wikidata.org/entity/Q3342427'), ('oName', "No Man's Land"), ('instance', 'http://www.wikidata.org/entity/Q25379'), ('instanceName', 'play')]
# [('o', 'http://www.wikidata.org/entity/Q3226375'), ('oName', 'The Homecoming'), ('instance', 'http://www.wikidata.org/entity/Q25379'), ('instanceName', 'play')]
# [('o', 'http://www.wikidata.org/entity/Q17103580'), ('oName', 'Chitra'), ('instance', 'http://www.wikidata.org/entity/Q25379'), ('instanceName', 'play')]
# [('o', 'http://www.wikidata.org/entity/Q2275694'), ('oName', 'The Dumb Waiter'), ('instance', 'http://www.wikidata.org/entity/Q25379'), ('instanceName', 'play')]
# [('o', 'http://www.wikidata.org/entity/Q2905016'), ('oName', 'The Room'), ('instance', 'http://www.wikidata.org/entity/Q25379'), ('instanceName', 'play')]
# [('o', 'http://www.wikidata.org/entity/Q3201743'), ('oName', 'The Lover'), ('instance', 'http://www.wikidata.org/entity/Q25379'), ('instanceName', 'play')]
# [('o', 'http://www.wikidata.org/entity/Q7285379'), ('oName', 'Raja'), ('instance', 'http://www.wikidata.org/entity/Q25379'), ('instanceName', 'play')]
# [('o', 'http://www.wikidata.org/entity/Q2930412'), ('oName', 'Old Times'), ('instance', 'http://www.wikidata.org/entity/Q25379'), ('instanceName', 'play')]
# [('o', 'http://www.wikidata.org/entity/Q3028771'), ('oName', 'Betrayal'), ('instance', 'http://www.wikidata.org/entity/Q25379'), ('instanceName', 'play')]
# 20

# %% [markdown]
# The instances of these works are the following one:

# %%
queryString = """
select distinct ?instance ?instanceName where {
    # ?author ^wdt:P1346|wdt:P166 wd:Q37922 .
    # ?o wdt:P50 ?author ;
        wdt:P31 ?instance .
    
    # ?instance <http://schema.org/name> ?instanceName .   
}
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('instance', 'http://www.wikidata.org/entity/Q17518557'), ('instanceName', 'collection of articles')]
# [('instance', 'http://www.wikidata.org/entity/Q1194583'), ('instanceName', 'one-act play')]
# [('instance', 'http://www.wikidata.org/entity/Q25379'), ('instanceName', 'play')]
# [('instance', 'http://www.wikidata.org/entity/Q49848'), ('instanceName', 'document')]
# [('instance', 'http://www.wikidata.org/entity/Q11483816'), ('instanceName', 'annual event')]
# [('instance', 'http://www.wikidata.org/entity/Q254554'), ('instanceName', 'picture book')]
# [('instance', 'http://www.wikidata.org/entity/Q732577'), ('instanceName', 'publication')]
# [('instance', 'http://www.wikidata.org/entity/Q7553'), ('instanceName', 'translation')]
# [('instance', 'http://www.wikidata.org/entity/Q105420'), ('instanceName', 'anthology')]
# [('instance', 'http://www.wikidata.org/entity/Q105543609'), ('instanceName', 'musical work/composition')]
# [('instance', 'http://www.wikidata.org/entity/Q13442814'), ('instanceName', 'scholarly article')]
# [('instance', 'http://www.wikidata.org/entity/Q17537576'), ('instanceName', 'creative work')]
# [('instance', 'http://www.wikidata.org/entity/Q2668072'), ('instanceName', 'collection')]
# [('instance', 'http://www.wikidata.org/entity/Q277759'), ('instanceName', 'book series')]
# [('instance', 'http://www.wikidata.org/entity/Q386724'), ('instanceName', 'work')]
# [('instance', 'http://www.wikidata.org/entity/Q4184'), ('instanceName', 'autobiography')]
# [('instance', 'http://www.wikidata.org/entity/Q47461344'), ('instanceName', 'written work')]
# [('instance', 'http://www.wikidata.org/entity/Q482'), ('instanceName', 'poetry')]
# [('instance', 'http://www.wikidata.org/entity/Q7725634'), ('instanceName', 'literary work')]
# [('instance', 'http://www.wikidata.org/entity/Q8261'), ('instanceName', 'novel')]
# [('instance', 'http://www.wikidata.org/entity/Q861911'), ('instanceName', 'speech')]
# [('instance', 'http://www.wikidata.org/entity/Q46337'), ('instanceName', 'manifesto')]
# [('instance', 'http://www.wikidata.org/entity/Q3331189'), ('instanceName', 'version, edition, or translation')]
# [('instance', 'http://www.wikidata.org/entity/Q37041'), ('instanceName', 'Classical Chinese')]
# [('instance', 'http://www.wikidata.org/entity/Q49084'), ('instanceName', 'short story')]
# [('instance', 'http://www.wikidata.org/entity/Q699'), ('instanceName', 'fairy tale')]
# [('instance', 'http://www.wikidata.org/entity/Q178651'), ('instanceName', 'interview')]
# [('instance', 'http://www.wikidata.org/entity/Q149537'), ('instanceName', 'novella')]
# [('instance', 'http://www.wikidata.org/entity/Q192239'), ('instanceName', 'historical novel')]
# [('instance', 'http://www.wikidata.org/entity/Q193955'), ('instanceName', 'hardback')]
# [('instance', 'http://www.wikidata.org/entity/Q220898'), ('instanceName', 'original video animation')]
# [('instance', 'http://www.wikidata.org/entity/Q5185279'), ('instanceName', 'poem')]
# [('instance', 'http://www.wikidata.org/entity/Q571'), ('instanceName', 'book')]
# [('instance', 'http://www.wikidata.org/entity/Q1631107'), ('instanceName', 'bibliography')]
# [('instance', 'http://www.wikidata.org/entity/Q103076'), ('instanceName', 'screenplay')]
# [('instance', 'http://www.wikidata.org/entity/Q191067'), ('instanceName', 'article')]
# [('instance', 'http://www.wikidata.org/entity/Q12106333'), ('instanceName', 'poetry collection')]
# [('instance', 'http://www.wikidata.org/entity/Q128093'), ('instanceName', 'e-book')]
# [('instance', 'http://www.wikidata.org/entity/Q1318295'), ('instanceName', 'narrative')]
# [('instance', 'http://www.wikidata.org/entity/Q1279564'), ('instanceName', 'short story collection')]
# [('instance', 'http://www.wikidata.org/entity/Q17991521'), ('instanceName', 'tale')]
# [('instance', 'http://www.wikidata.org/entity/Q2188189'), ('instanceName', 'musical work')]
# [('instance', 'http://www.wikidata.org/entity/Q27560760'), ('instanceName', 'сollection of fairy tales')]
# [('instance', 'http://www.wikidata.org/entity/Q39811647'), ('instanceName', 'translated work')]
# [('instance', 'http://www.wikidata.org/entity/Q7777570'), ('instanceName', 'theatrical production')]
# [('instance', 'http://www.wikidata.org/entity/Q1238720'), ('instanceName', 'volume')]
# [('instance', 'http://www.wikidata.org/entity/Q149010'), ('instanceName', 'trilogy')]
# [('instance', 'http://www.wikidata.org/entity/Q55738783'), ('instanceName', 'myth')]
# [('instance', 'http://www.wikidata.org/entity/Q17710980'), ('instanceName', 'literary tetralogy')]
# [('instance', 'http://www.wikidata.org/entity/Q30070590'), ('instanceName', 'magazine article')]
# [('instance', 'http://www.wikidata.org/entity/Q1772'), ('instanceName', 'epitaph')]
# [('instance', 'http://www.wikidata.org/entity/Q53731850'), ('instanceName', 'individual copy of a book')]
# [('instance', 'http://www.wikidata.org/entity/Q867335'), ('instanceName', 'literary cycle')]
# [('instance', 'http://www.wikidata.org/entity/Q20225034'), ('instanceName', 'unfinished novel')]
# [('instance', 'http://www.wikidata.org/entity/Q1440453'), ('instanceName', 'literary fragment')]
# [('instance', 'http://www.wikidata.org/entity/Q234460'), ('instanceName', 'text')]
# [('instance', 'http://www.wikidata.org/entity/Q20937557'), ('instanceName', 'series')]
# [('instance', 'http://www.wikidata.org/entity/Q17362920'), ('instanceName', 'Wikimedia duplicated page')]
# [('instance', 'http://www.wikidata.org/entity/Q5707594'), ('instanceName', 'news article')]
# [('instance', 'http://www.wikidata.org/entity/Q1255689'), ('instanceName', 'drame lyrique')]
# [('instance', 'http://www.wikidata.org/entity/Q133492'), ('instanceName', 'letter')]
# [('instance', 'http://www.wikidata.org/entity/Q26876682'), ('instanceName', 'personal bibliography')]
# [('instance', 'http://www.wikidata.org/entity/Q5248657'), ('instanceName', 'debut novel')]
# [('instance', 'http://www.wikidata.org/entity/Q11424'), ('instanceName', 'film')]
# [('instance', 'http://www.wikidata.org/entity/Q3377406'), ('instanceName', 'political catch phrase')]
# [('instance', 'http://www.wikidata.org/entity/Q35760'), ('instanceName', 'essay')]
# [('instance', 'http://www.wikidata.org/entity/Q13593966'), ('instanceName', 'literary trilogy')]
# [('instance', 'http://www.wikidata.org/entity/Q15841920'), ('instanceName', 'Redewendung')]
# [('instance', 'http://www.wikidata.org/entity/Q1980247'), ('instanceName', 'chapter')]
# [('instance', 'http://www.wikidata.org/entity/Q1667921'), ('instanceName', 'novel series')]
# [('instance', 'http://www.wikidata.org/entity/Q2635894'), ('instanceName', 'radio drama')]
# [('instance', 'http://www.wikidata.org/entity/Q474090'), ('instanceName', 'narrative poetry')]
# [('instance', 'http://www.wikidata.org/entity/Q58483083'), ('instanceName', 'dramatico-musical work')]
# [('instance', 'http://www.wikidata.org/entity/Q7725310'), ('instanceName', 'series of creative works')]
# [('instance', 'http://www.wikidata.org/entity/Q1346592'), ('instanceName', 'bitext')]
# [('instance', 'http://www.wikidata.org/entity/Q124922'), ('instanceName', 'reportage')]
# [('instance', 'http://www.wikidata.org/entity/Q17710986'), ('instanceName', 'literary pentalogy')]
# [('instance', 'http://www.wikidata.org/entity/Q16324495'), ('instanceName', 'essay collection')]
# [('instance', 'http://www.wikidata.org/entity/Q30749496'), ('instanceName', 'diploma thesis')]
# [('instance', 'http://www.wikidata.org/entity/Q2339879'), ('instanceName', 'dramatic monologue')]
# [('instance', 'http://www.wikidata.org/entity/Q1661'), ('instanceName', 'verse')]
# [('instance', 'http://www.wikidata.org/entity/Q506240'), ('instanceName', 'television film')]
# [('instance', 'http://www.wikidata.org/entity/Q1009641'), ('instanceName', 'Bunkobon')]
# [('instance', 'http://www.wikidata.org/entity/Q36279'), ('instanceName', 'biography')]
# [('instance', 'http://www.wikidata.org/entity/Q20655472'), ('instanceName', 'editorial collection')]
# [('instance', 'http://www.wikidata.org/entity/Q58854'), ('instanceName', 'literary criticism')]
# [('instance', 'http://www.wikidata.org/entity/Q1497584'), ('instanceName', 'cycle of poems')]
# [('instance', 'http://www.wikidata.org/entity/Q59126'), ('instanceName', 'xiaoshuo')]
# [('instance', 'http://www.wikidata.org/entity/Q55713039'), ('instanceName', 'multilingual dictionary')]
# [('instance', 'http://www.wikidata.org/entity/Q10880526'), ('instanceName', 'prosody')]
# [('instance', 'http://www.wikidata.org/entity/Q128758'), ('instanceName', 'satire')]
# [('instance', 'http://www.wikidata.org/entity/Q196600'), ('instanceName', 'media franchise')]
# [('instance', 'http://www.wikidata.org/entity/Q25372'), ('instanceName', 'drama')]
# [('instance', 'http://www.wikidata.org/entity/Q4167836'), ('instanceName', 'Wikimedia category')]
# [('instance', 'http://www.wikidata.org/entity/Q131539'), ('instanceName', "children's literature")]
# [('instance', 'http://www.wikidata.org/entity/Q182357'), ('instanceName', 'lyric poetry')]
# [('instance', 'http://www.wikidata.org/entity/Q19389637'), ('instanceName', 'biographical article')]
# [('instance', 'http://www.wikidata.org/entity/Q12799318'), ('instanceName', 'short novel')]
# [('instance', 'http://www.wikidata.org/entity/Q17489659'), ('instanceName', 'group of works')]
# [('instance', 'http://www.wikidata.org/entity/Q87167'), ('instanceName', 'manuscript')]
# [('instance', 'http://www.wikidata.org/entity/Q35140'), ('instanceName', 'performance')]
# [('instance', 'http://www.wikidata.org/entity/Q17518870'), ('instanceName', 'group of literary works')]
# [('instance', 'http://www.wikidata.org/entity/Q1978454'), ('instanceName', 'complete works')]
# [('instance', 'http://www.wikidata.org/entity/Q43099869'), ('instanceName', 'dance production')]
# [('instance', 'http://www.wikidata.org/entity/Q17586363'), ('instanceName', 'poetry collection')]
# [('instance', 'http://www.wikidata.org/entity/Q47467768'), ('instanceName', 'operatic production')]
# 106

# %% [markdown]
# The fact that the entites are instances of books, poem and so on confirm that the property author is the one I am looking for. I can initially try to see if there are some properties that connects the books or poems or works directly to the Vatican Library.

# %%
queryString = """
select distinct ?p ?pName where {
    # ?author ^wdt:P1346|wdt:P166 wd:Q37922 .
    
    # ?book wdt:P50 ?author ;
          # ?p wd:Q213678 .
    
    # ?p <http://schema.org/name> ?pName .
}
"""

print("Results")
run_query(queryString)
# Out:
# Results
# Empty
# 0

# %% [markdown]
# There are no results, so maybe there are some other entities in the middle. First, I can see which entities are connected to the Vatican Library and their properties.

# %%
queryString = """
select distinct ?o ?oName ?p ?pName {
    # ?o ?p wd:Q213678 .
    
    # ?p <http://schema.org/name> ?pName .
    # ?o <http://schema.org/name> ?oName .
} limit 100
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('o', 'http://www.wikidata.org/entity/Q17174857'), ('oName', 'Bibbia di Federico da Montefeltro - BAV Urb.Lat.1&2'), ('p', 'http://www.wikidata.org/prop/direct/P195'), ('pName', 'collection')]
# [('o', 'http://www.wikidata.org/entity/Q2754987'), ('oName', 'Leopoldo Cicognara'), ('p', 'http://www.wikidata.org/prop/direct/P9419'), ('pName', 'personal library at')]
# [('o', 'http://www.wikidata.org/entity/Q209285'), ('oName', 'Codex Vaticanus'), ('p', 'http://www.wikidata.org/prop/direct/P195'), ('pName', 'collection')]
# [('o', 'http://www.wikidata.org/entity/Q7075'), ('oName', 'library'), ('p', 'http://www.wikidata.org/prop/direct/P5869'), ('pName', 'model item')]
# [('o', 'http://www.wikidata.org/entity/Q19823475'), ('oName', 'prefect of the Vatican Library'), ('p', 'http://www.wikidata.org/prop/direct/P2389'), ('pName', 'organization directed by the office or position')]
# [('o', 'http://www.wikidata.org/entity/Q1806588'), ('oName', 'Lasimos Krater'), ('p', 'http://www.wikidata.org/prop/direct/P195'), ('pName', 'collection')]
# [('o', 'http://www.wikidata.org/entity/Q664820'), ('oName', 'Bodmer Papyri'), ('p', 'http://www.wikidata.org/prop/direct/P195'), ('pName', 'collection')]
# [('o', 'http://www.wikidata.org/entity/Q711620'), ('oName', 'Stefano Evodio Assemani'), ('p', 'http://www.wikidata.org/prop/direct/P108'), ('pName', 'employer')]
# [('o', 'http://www.wikidata.org/entity/Q1106341'), ('oName', 'Codex Vaticanus Graecus 64'), ('p', 'http://www.wikidata.org/prop/direct/P195'), ('pName', 'collection')]
# [('o', 'http://www.wikidata.org/entity/Q3592714'), ('oName', 'Barberini Gospels'), ('p', 'http://www.wikidata.org/prop/direct/P195'), ('pName', 'collection')]
# [('o', 'http://www.wikidata.org/entity/Q3592714'), ('oName', 'Barberini Gospels'), ('p', 'http://www.wikidata.org/prop/direct/P276'), ('pName', 'location')]
# [('o', 'http://www.wikidata.org/entity/Q16653651'), ('oName', 'Divina Commedia de Federigo da Montefeltro - BAVaticana UrbLat365'), ('p', 'http://www.wikidata.org/prop/direct/P195'), ('pName', 'collection')]
# [('o', 'http://www.wikidata.org/entity/Q903320'), ('oName', 'Book of Dede Korkut'), ('p', 'http://www.wikidata.org/prop/direct/P195'), ('pName', 'collection')]
# [('o', 'http://www.wikidata.org/entity/Q101438843'), ('oName', 'Rossiana Library'), ('p', 'http://www.wikidata.org/prop/direct/P195'), ('pName', 'collection')]
# [('o', 'http://www.wikidata.org/entity/Q101438843'), ('oName', 'Rossiana Library'), ('p', 'http://www.wikidata.org/prop/direct/P276'), ('pName', 'location')]
# [('o', 'http://www.wikidata.org/entity/Q101438843'), ('oName', 'Rossiana Library'), ('p', 'http://www.wikidata.org/prop/direct/P361'), ('pName', 'part of')]
# [('o', 'http://www.wikidata.org/entity/Q61749291'), ('oName', 'Rare books in the Vatican Library\u202f: reshaping the catalogue'), ('p', 'http://www.wikidata.org/prop/direct/P921'), ('pName', 'main subject')]
# [('o', 'http://www.wikidata.org/entity/Q61727287'), ('oName', 'Paola Manoni'), ('p', 'http://www.wikidata.org/prop/direct/P1416'), ('pName', 'affiliation')]
# [('o', 'http://www.wikidata.org/entity/Q61728093'), ('oName', 'Metadata framework and application profiles in the global structure of catalogs and digitization projects of the Vatican Library'), ('p', 'http://www.wikidata.org/prop/direct/P921'), ('pName', 'main subject')]
# [('o', 'http://www.wikidata.org/entity/Q3606806'), ('oName', 'Agostino Paravicini Bagliani'), ('p', 'http://www.wikidata.org/prop/direct/P108'), ('pName', 'employer')]
# [('o', 'http://www.wikidata.org/entity/P9522'), ('oName', 'Biblioteca di Santa Sabina ID'), ('p', 'http://www.wikidata.org/prop/direct/P1855'), ('pName', 'Wikidata property example')]
# [('o', 'http://www.wikidata.org/entity/Q1531846'), ('oName', 'Vergilius Vaticanus'), ('p', 'http://www.wikidata.org/prop/direct/P195'), ('pName', 'collection')]
# [('o', 'http://www.wikidata.org/entity/Q1937608'), ('oName', 'Minuscule 131'), ('p', 'http://www.wikidata.org/prop/direct/P195'), ('pName', 'collection')]
# [('o', 'http://www.wikidata.org/entity/Q104161636'), ('oName', 'Ángela Núñez Gaitán'), ('p', 'http://www.wikidata.org/prop/direct/P1416'), ('pName', 'affiliation')]
# [('o', 'http://www.wikidata.org/entity/Q1230408'), ('oName', 'Gugliemo Sirleto'), ('p', 'http://www.wikidata.org/prop/direct/P108'), ('pName', 'employer')]
# [('o', 'http://www.wikidata.org/entity/Q21545450'), ('oName', 'Pietro Matranga'), ('p', 'http://www.wikidata.org/prop/direct/P108'), ('pName', 'employer')]
# [('o', 'http://www.wikidata.org/entity/Q105478445'), ('oName', 'Massimo Ceresa'), ('p', 'http://www.wikidata.org/prop/direct/P108'), ('pName', 'employer')]
# [('o', 'http://www.wikidata.org/entity/Q338714'), ('oName', 'Anjou Legendarium'), ('p', 'http://www.wikidata.org/prop/direct/P195'), ('pName', 'collection')]
# [('o', 'http://www.wikidata.org/entity/Q338714'), ('oName', 'Anjou Legendarium'), ('p', 'http://www.wikidata.org/prop/direct/P276'), ('pName', 'location')]
# [('o', 'http://www.wikidata.org/entity/Q26972432'), ('oName', 'Osvaldo Raineri'), ('p', 'http://www.wikidata.org/prop/direct/P108'), ('pName', 'employer')]
# [('o', 'http://www.wikidata.org/entity/Q554853'), ('oName', 'Giuseppe Simone Assemani'), ('p', 'http://www.wikidata.org/prop/direct/P108'), ('pName', 'employer')]
# [('o', 'http://www.wikidata.org/entity/Q774565'), ('oName', 'Codex Vaticanus 354'), ('p', 'http://www.wikidata.org/prop/direct/P195'), ('pName', 'collection')]
# [('o', 'http://www.wikidata.org/entity/Q1250195'), ('oName', 'Codex Assemanius'), ('p', 'http://www.wikidata.org/prop/direct/P195'), ('pName', 'collection')]
# [('o', 'http://www.wikidata.org/entity/Q1250195'), ('oName', 'Codex Assemanius'), ('p', 'http://www.wikidata.org/prop/direct/P276'), ('pName', 'location')]
# [('o', 'http://www.wikidata.org/entity/Q3802491'), ('oName', 'Isidoro Carini'), ('p', 'http://www.wikidata.org/prop/direct/P108'), ('pName', 'employer')]
# [('o', 'http://www.wikidata.org/entity/Q1106235'), ('oName', 'Codex Ríos'), ('p', 'http://www.wikidata.org/prop/direct/P195'), ('pName', 'collection')]
# [('o', 'http://www.wikidata.org/entity/Q1106235'), ('oName', 'Codex Ríos'), ('p', 'http://www.wikidata.org/prop/direct/P276'), ('pName', 'location')]
# [('o', 'http://www.wikidata.org/entity/Q785039'), ('oName', 'Joshua Roll'), ('p', 'http://www.wikidata.org/prop/direct/P195'), ('pName', 'collection')]
# [('o', 'http://www.wikidata.org/entity/Q536191'), ('oName', 'Angelo Mercati'), ('p', 'http://www.wikidata.org/prop/direct/P108'), ('pName', 'employer')]
# [('o', 'http://www.wikidata.org/entity/Q33231619'), ('oName', 'breviary of  Matthias Corvin'), ('p', 'http://www.wikidata.org/prop/direct/P195'), ('pName', 'collection')]
# [('o', 'http://www.wikidata.org/entity/Q33231619'), ('oName', 'breviary of  Matthias Corvin'), ('p', 'http://www.wikidata.org/prop/direct/P276'), ('pName', 'location')]
# [('o', 'http://www.wikidata.org/entity/Q84353965'), ('oName', 'opac.vatlib.it'), ('p', 'http://www.wikidata.org/prop/direct/P127'), ('pName', 'owned by')]
# [('o', 'http://www.wikidata.org/entity/Q84353965'), ('oName', 'opac.vatlib.it'), ('p', 'http://www.wikidata.org/prop/direct/P137'), ('pName', 'operator')]
# [('o', 'http://www.wikidata.org/entity/Q106375119'), ('oName', 'Antonio Sacco'), ('p', 'http://www.wikidata.org/prop/direct/P108'), ('pName', 'employer')]
# [('o', 'http://www.wikidata.org/entity/Q65122273'), ('oName', 'Andrew, the Apostle'), ('p', 'http://www.wikidata.org/prop/direct/P195'), ('pName', 'collection')]
# [('o', 'http://www.wikidata.org/entity/Q77463414'), ('oName', 'Apostolic Library Regina 1682'), ('p', 'http://www.wikidata.org/prop/direct/P195'), ('pName', 'collection')]
# [('o', 'http://www.wikidata.org/entity/Q77463414'), ('oName', 'Apostolic Library Regina 1682'), ('p', 'http://www.wikidata.org/prop/direct/P276'), ('pName', 'location')]
# [('o', 'http://www.wikidata.org/entity/Q77463433'), ('oName', 'Apostolic Library Reg. 1323'), ('p', 'http://www.wikidata.org/prop/direct/P195'), ('pName', 'collection')]
# [('o', 'http://www.wikidata.org/entity/Q77463433'), ('oName', 'Apostolic Library Reg. 1323'), ('p', 'http://www.wikidata.org/prop/direct/P276'), ('pName', 'location')]
# [('o', 'http://www.wikidata.org/entity/Q55831099'), ('oName', 'Codex vaticanus latinus 3199'), ('p', 'http://www.wikidata.org/prop/direct/P195'), ('pName', 'collection')]
# [('o', 'http://www.wikidata.org/entity/Q55831099'), ('oName', 'Codex vaticanus latinus 3199'), ('p', 'http://www.wikidata.org/prop/direct/P276'), ('pName', 'location')]
# [('o', 'http://www.wikidata.org/entity/Q3460976'), ('oName', 'Gregorian Sacramentary'), ('p', 'http://www.wikidata.org/prop/direct/P195'), ('pName', 'collection')]
# [('o', 'http://www.wikidata.org/entity/Q16912485'), ('oName', 'Divine Comedy Illustrated by Botticelli'), ('p', 'http://www.wikidata.org/prop/direct/P276'), ('pName', 'location')]
# [('o', 'http://www.wikidata.org/entity/Q16939517'), ('oName', 'Codex Parisino-petropolitanus'), ('p', 'http://www.wikidata.org/prop/direct/P195'), ('pName', 'collection')]
# [('o', 'http://www.wikidata.org/entity/Q16939517'), ('oName', 'Codex Parisino-petropolitanus'), ('p', 'http://www.wikidata.org/prop/direct/P276'), ('pName', 'location')]
# [('o', 'http://www.wikidata.org/entity/Q744655'), ('oName', 'Chigi codex'), ('p', 'http://www.wikidata.org/prop/direct/P195'), ('pName', 'collection')]
# [('o', 'http://www.wikidata.org/entity/Q744655'), ('oName', 'Chigi codex'), ('p', 'http://www.wikidata.org/prop/direct/P276'), ('pName', 'location')]
# [('o', 'http://www.wikidata.org/entity/Q5140259'), ('oName', 'Codex Vaticanus Latinus 3868'), ('p', 'http://www.wikidata.org/prop/direct/P195'), ('pName', 'collection')]
# [('o', 'http://www.wikidata.org/entity/Q5140259'), ('oName', 'Codex Vaticanus Latinus 3868'), ('p', 'http://www.wikidata.org/prop/direct/P276'), ('pName', 'location')]
# [('o', 'http://www.wikidata.org/entity/Q1285827'), ('oName', 'Liber Censuum'), ('p', 'http://www.wikidata.org/prop/direct/P195'), ('pName', 'collection')]
# [('o', 'http://www.wikidata.org/entity/Q1106357'), ('oName', 'Codex Vaticanus 2061'), ('p', 'http://www.wikidata.org/prop/direct/P195'), ('pName', 'collection')]
# [('o', 'http://www.wikidata.org/entity/Q59154964'), ('oName', 'The Vatican Library in Andrea Fulvio’s De bibliothecis antiquis : a new model of librarian reality'), ('p', 'http://www.wikidata.org/prop/direct/P921'), ('pName', 'main subject')]
# [('o', 'http://www.wikidata.org/entity/Q108548100'), ('oName', 'Church Slavonic vita of Saint Wenceslaus'), ('p', 'http://www.wikidata.org/prop/direct/P195'), ('pName', 'collection')]
# [('o', 'http://www.wikidata.org/entity/Q28045402'), ('oName', 'Barbara Jatta'), ('p', 'http://www.wikidata.org/prop/direct/P108'), ('pName', 'employer')]
# [('o', 'http://www.wikidata.org/entity/Q251409'), ('oName', 'Codex Petropolitanus Purpureus'), ('p', 'http://www.wikidata.org/prop/direct/P195'), ('pName', 'collection')]
# [('o', 'http://www.wikidata.org/entity/Q3057287'), ('oName', 'Ernst Steinmann'), ('p', 'http://www.wikidata.org/prop/direct/P485'), ('pName', 'archives at')]
# [('o', 'http://www.wikidata.org/entity/Q103916575'), ('oName', 'Anna Berloco'), ('p', 'http://www.wikidata.org/prop/direct/P1416'), ('pName', 'affiliation')]
# [('o', 'http://www.wikidata.org/entity/Q916549'), ('oName', 'Indiculus superstitionum et paganiarum'), ('p', 'http://www.wikidata.org/prop/direct/P195'), ('pName', 'collection')]
# [('o', 'http://www.wikidata.org/entity/Q1798543'), ('oName', 'Uncial 054'), ('p', 'http://www.wikidata.org/prop/direct/P195'), ('pName', 'collection')]
# [('o', 'http://www.wikidata.org/entity/Q6512274'), ('oName', 'Lectionary 36'), ('p', 'http://www.wikidata.org/prop/direct/P195'), ('pName', 'collection')]
# [('o', 'http://www.wikidata.org/entity/Q3792221'), ('oName', 'Igino Giordani'), ('p', 'http://www.wikidata.org/prop/direct/P108'), ('pName', 'employer')]
# [('o', 'http://www.wikidata.org/entity/Q3561145'), ('oName', 'Vita Mathildis'), ('p', 'http://www.wikidata.org/prop/direct/P195'), ('pName', 'collection')]
# [('o', 'http://www.wikidata.org/entity/Q58954040'), ('oName', 'On an edition of ecclesiastical books catalogues between XVIth and XVIIth centuries. Reflections and research purposes'), ('p', 'http://www.wikidata.org/prop/direct/P921'), ('pName', 'main subject')]
# [('o', 'http://www.wikidata.org/entity/Q93234134'), ('oName', 'Giancarlo Alteri'), ('p', 'http://www.wikidata.org/prop/direct/P108'), ('pName', 'employer')]
# [('o', 'http://www.wikidata.org/entity/Q106517940'), ('oName', 'The Digital Cicognara Library'), ('p', 'http://www.wikidata.org/prop/direct/P1416'), ('pName', 'affiliation')]
# [('o', 'http://www.wikidata.org/entity/Q96272045'), ('oName', 'Raffaella Vincenti'), ('p', 'http://www.wikidata.org/prop/direct/P108'), ('pName', 'employer')]
# [('o', 'http://www.wikidata.org/entity/Q663118'), ('oName', 'Bible of San Paolo fuori le Mura'), ('p', 'http://www.wikidata.org/prop/direct/P195'), ('pName', 'collection')]
# [('o', 'http://www.wikidata.org/entity/Q2758161'), ('oName', 'Gelasian Sacramentary'), ('p', 'http://www.wikidata.org/prop/direct/P195'), ('pName', 'collection')]
# [('o', 'http://www.wikidata.org/entity/Q2758161'), ('oName', 'Gelasian Sacramentary'), ('p', 'http://www.wikidata.org/prop/direct/P276'), ('pName', 'location')]
# [('o', 'http://www.wikidata.org/entity/Q6756199'), ('oName', 'Marcel Richard'), ('p', 'http://www.wikidata.org/prop/direct/P108'), ('pName', 'employer')]
# [('o', 'http://www.wikidata.org/entity/Q104163508'), ('oName', 'Manutenere, conservare ac innovari'), ('p', 'http://www.wikidata.org/prop/direct/P921'), ('pName', 'main subject')]
# [('o', 'http://www.wikidata.org/entity/Q594213'), ('oName', 'Aldobrandini Wedding'), ('p', 'http://www.wikidata.org/prop/direct/P276'), ('pName', 'location')]
# [('o', 'http://www.wikidata.org/entity/Q8229359'), ('oName', 'Category:Vatican Library'), ('p', 'http://www.wikidata.org/prop/direct/P301'), ('pName', "category's main topic")]
# [('o', 'http://www.wikidata.org/entity/Q2258615'), ('oName', 'Rossi Codex'), ('p', 'http://www.wikidata.org/prop/direct/P276'), ('pName', 'location')]
# [('o', 'http://www.wikidata.org/entity/Q15841047'), ('oName', 'Prochiron legum'), ('p', 'http://www.wikidata.org/prop/direct/P195'), ('pName', 'collection')]
# [('o', 'http://www.wikidata.org/entity/P1017'), ('oName', 'Vatican Library ID (former scheme)'), ('p', 'http://www.wikidata.org/prop/direct/P2378'), ('pName', 'issued by')]
# [('o', 'http://www.wikidata.org/entity/P1017'), ('oName', 'Vatican Library ID (former scheme)'), ('p', 'http://www.wikidata.org/prop/direct/P1629'), ('pName', 'Wikidata item of this property')]
# [('o', 'http://www.wikidata.org/entity/Q218974'), ('oName', 'Codex Aureus of Lorsch'), ('p', 'http://www.wikidata.org/prop/direct/P195'), ('pName', 'collection')]
# [('o', 'http://www.wikidata.org/entity/Q105426233'), ('oName', 'Chart of the World (copy) Inv. 5R'), ('p', 'http://www.wikidata.org/prop/direct/P361'), ('pName', 'part of')]
# [('o', 'http://www.wikidata.org/entity/Q1918574'), ('oName', 'Menologion of Basil II'), ('p', 'http://www.wikidata.org/prop/direct/P195'), ('pName', 'collection')]
# [('o', 'http://www.wikidata.org/entity/Q77464627'), ('oName', 'Cod. Palat. lat. 1074'), ('p', 'http://www.wikidata.org/prop/direct/P195'), ('pName', 'collection')]
# [('o', 'http://www.wikidata.org/entity/Q77464627'), ('oName', 'Cod. Palat. lat. 1074'), ('p', 'http://www.wikidata.org/prop/direct/P276'), ('pName', 'location')]
# [('o', 'http://www.wikidata.org/entity/Q3656584'), ('oName', 'Canzoniere Vaticano latino 3793'), ('p', 'http://www.wikidata.org/prop/direct/P276'), ('pName', 'location')]
# [('o', 'http://www.wikidata.org/entity/Q1258536'), ('oName', 'Codex Urbinas'), ('p', 'http://www.wikidata.org/prop/direct/P195'), ('pName', 'collection')]
# [('o', 'http://www.wikidata.org/entity/Q21207482'), ('oName', 'Enrico Carusi'), ('p', 'http://www.wikidata.org/prop/direct/P108'), ('pName', 'employer')]
# [('o', 'http://www.wikidata.org/entity/Q105962278'), ('oName', 'Dante Urbinate 365'), ('p', 'http://www.wikidata.org/prop/direct/P195'), ('pName', 'collection')]
# [('o', 'http://www.wikidata.org/entity/Q105962278'), ('oName', 'Dante Urbinate 365'), ('p', 'http://www.wikidata.org/prop/direct/P276'), ('pName', 'location')]
# [('o', 'http://www.wikidata.org/entity/Q1180580'), ('oName', 'De arte venandi cum avibus'), ('p', 'http://www.wikidata.org/prop/direct/P195'), ('pName', 'collection')]
# [('o', 'http://www.wikidata.org/entity/Q1180580'), ('oName', 'De arte venandi cum avibus'), ('p', 'http://www.wikidata.org/prop/direct/P276'), ('pName', 'location')]
# [('o', 'http://www.wikidata.org/entity/Q4156450'), ('oName', 'Robert Devreesse'), ('p', 'http://www.wikidata.org/prop/direct/P108'), ('pName', 'employer')]
# 100

# %% [markdown]
# Probably the property *part of (**P361**)* can play a role in found what I am looking for. Maybe books are located in other libraries which are part of the Vatican Library.

# %%
queryString = """
select distinct ?p ?pName where {
    # ?author ^wdt:P1346|wdt:P166 wd:Q37922 .
    
    # ?book wdt:P50 ?author ;
          # ?p ?library .
    
    # ?library wdt:P361* wd:Q213678 .
    
    # ?p <http://schema.org/name> ?pName .
}
"""

print("Results")
run_query(queryString)
# Out:
# Results
# Empty
# 0

# %% [markdown]
# Also in this case, there are no connections between the books written by nobel laureates and the Vatican Library.

# %% [markdown]
# I conclude that in the database there are no works written by Literature Nobel Laureates that are part of the Vatican Library. I can in any case see if there is a property "vatican" in the laureates properties.

# %%
queryString = """
select distinct ?p ?pName where {
    # ?author ^wdt:P1346|wdt:P166 wd:Q37922 ;
            # ?p ?o .
        
    # ?p <http://schema.org/name> ?pName .
    
    filter (regex(?pName, "vatica", "i"))
}
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P1017'), ('pName', 'Vatican Library ID (former scheme)')]
# [('p', 'http://www.wikidata.org/prop/direct/P8034'), ('pName', 'Vatican Library VcBA ID')]
# 2

# %% [markdown]
# The vatican library ID doesn't provide informations abouts books written, but can give us informatio if the author has written books contained in the Vatican Library. I can use this information to count the number of nobel laureates that has this property.

# %%
queryString = """
select (count(distinct ?author) as ?numAuthors) where {
    # ?author ^wdt:P1346|wdt:P166 wd:Q37922 ;
            wdt:P1017|wdt:P8034 ?o .
}
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('numAuthors', '75')]
# 1

# %% [markdown]
# The number of authors with a relation with the Vatican Library are 75 on a total of Literature Laureates of 118, so probably 43 laureates never wrote a book contained in the Vatican Library.

# %% [markdown]
# # General instructions
#
# The goal of the project is to materialize a set of **exploratory workloads** over a real-world, large-scale,  open-domain KG: [WikiData](https://www.wikidata.org/wiki/Wikidata:Main_Page)
#
# An exploratory workload  is composed by a set of queries, where each query is related to the information obtained previously.
#
# An exploratory workload starts with a usually vague, open ended question, and does not assume the person issuing the workload has a clear understanding of the data contained in the target database or its structure.
#
# Remeber that:
#
# 1. All the queries must run in the python notebook
# 2. You can use classes and properties only if you find them via a SPARQL query that must be present in the notebook
# 3. You do not delete useless queries. Keep everything that is synthatically valid
#
# ```
# ?p <http://schema.org/name> ?name .
# ```
#
# is the BGP returning a human-readable name of a property or a class in Wikidata.

# %%
## SETUP used later

from SPARQLWrapper import SPARQLWrapper, JSON


prefixString = """
##-77c320cba1-## 
PREFIX wd: <http://www.wikidata.org/entity/> 
PREFIX wdt: <http://www.wikidata.org/prop/direct/> 
PREFIX sc: <http://schema.org/>
"""

# select and construct queries
def run_query(queryString):
    to_run = prefixString + "\n" + queryString

    sparql = SPARQLWrapper("http://a256-gc1-02.srv.aau.dk:5820/sparql")
    sparql.setTimeout(300)
    sparql.setReturnFormat(JSON)
    sparql.setQuery(to_run)

    try :
       results = sparql.query()
       json_results = results.convert()
       if len(json_results['results']['bindings'])==0:
          print("Empty")
          return 0
    
       for bindings in json_results['results']['bindings']:
          print( [ (var, value['value'])  for var, value in bindings.items() ] )

       return len(json_results['results']['bindings'])

    except Exception as e :
        print("The operation failed", e)
    
# ASk queries
def run_ask_query(queryString):
    to_run = prefixString + "\n" + queryString

    sparql = SPARQLWrapper("http://a256-gc1-03.srv.aau.dk:5820/sparql")
    sparql.setTimeout(300)
    sparql.setReturnFormat(JSON)
    sparql.setQuery(to_run)

    try :
        return sparql.query().convert()

    except Exception as e :
        print("The operation failed", e)

# %% [markdown]
# # Politics Workflow Series ("Monarchies")
#
# Consider the following exploratory information need:
#
# > You investigating existing and past historical monarchies

# %% [markdown]
# ## Useful URIs for the current workflow
#
#
# The following are given:
#
# | IRI           | Description   | Role      |
# | -----------   | -----------   |-----------|
# | `wdt:P1647`   | subproperty   | predicate |
# | `wdt:P31`     | instance of   | predicate |
# | `wdt:P279`    | subclass      | predicate |
# | `wdt:P17`     | country       | predicate |
# | `wdt:P27`     | citizenship   | predicate |
# | `wdt:P1366`   | replaced by    | predicate |
# | `wdt:P122`    | basic form of government    | predicate |
# | `wd:Q38`      | Italy          | node |
# | `wd:Q145`     | United Kingdom           | node |
# | `wd:Q7269`    | monarchy           | node |
#
#
#
#
# Also consider
#
# ```
# ?p (wdt:P31|wdt:P122)/wdt:P279* wd:Q7269  .
# ```
#
# is the BGP to retrieve all **countries that are some instance of a monarchy**

# %% [markdown]
# ## Workload Goals
#
#
# 1. Identify the BGP to retrieve states that were monarchies and have been replaced by some other state
#
# 2. Identify the BGP for obtaining statistical information of monarchies, e.g., poluation or inception date
#
# 3. Which is or was  the country with the highest population?
#
# 4. How many countries are or have been monarchies across continents?
#
# 5. Analyze the number of countries that were monarchies
#
#    5.1 How many sub-types of monarchy exist?  How many instances of exist of each one?
#
#    5.2 Are there cities that have been capital of multiple kingdoms?
#
#    5.3 Which are the top-3 monarchies with the earliest inception and still existing?

# %%
# start your workflow here

# %%
queryString = """
SELECT COUNT(*)
WHERE { 

# ?p (wdt:P31|wdt:P122)/wdt:P279* wd:Q7269  . 
} 
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('callret-0', '2344')]
# 1

# %%
1. Identify the BGP to retrieve states that were monarchies and have been replaced by some other state

# %%
# find the state values replace by->P1366 , continent->P30 and capital->P36
queryString = """
SELECT distinct ?p ?pname
WHERE { 

# ?country (wdt:P31|wdt:P122)/wdt:P279* wd:Q7269  ; 
        # ?p ?o.filter(!isliteral(?o))
        
# ?p sc:name ?pname.


} 
limit 5
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P1080'), ('pname', 'from narrative universe')]
# [('p', 'http://www.wikidata.org/prop/direct/P112'), ('pname', 'founded by')]
# [('p', 'http://www.wikidata.org/prop/direct/P1151'), ('pname', "topic's main Wikimedia portal")]
# [('p', 'http://www.wikidata.org/prop/direct/P122'), ('pname', 'basic form of government')]
# [('p', 'http://www.wikidata.org/prop/direct/P1269'), ('pname', 'facet of')]
# 5

# %%
# get all states which were replaced by a new state
queryString = """
SELECT distinct ?countryname ?replacebyname
WHERE { 

# ?country (wdt:P31|wdt:P122)/wdt:P279* wd:Q7269  ; 
         wdt:P1366 ?replaceby.
        
# ?country sc:name ?countryname.     
# ?replaceby sc:name ?replacebyname.


} 
limit 5
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('countryname', 'Jodhpur State'), ('replacebyname', 'India')]
# [('countryname', 'Eastern Hungarian Kingdom'), ('replacebyname', 'Principality of Transylvania')]
# [('countryname', 'East Francia'), ('replacebyname', 'Holy Roman Empire')]
# [('countryname', 'Kingdom of Hawaiʻi'), ('replacebyname', 'Republic of Hawaii')]
# [('countryname', 'Duchy of Luxembourg'), ('replacebyname', 'French First Republic')]
# 5

# %%
2. Identify the BGP for obtaining statistical information of monarchies, e.g., poluation or inception date

# %%
# find statistical information  poluation->P1082 , inception date->P571 religion->P140, time period->P2348)
queryString = """
SELECT distinct ?p ?pname
WHERE { 

# ?country (wdt:P31|wdt:P122)/wdt:P279* wd:Q7269  ; 
        # ?p ?o.
        
# ?p sc:name ?pname.       
filter regex(?pname,"inception|population",'i')        



} 
#limit 5
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P1082'), ('pname', 'population')]
# [('p', 'http://www.wikidata.org/prop/direct/P571'), ('pname', 'inception')]
# 2

# %%
# find statistical information  poluation->P1082 , inception date->P571 religion->P140, time period->P2348)
queryString = """
SELECT distinct ?countryname ?poluation ?periodname ?religionname
WHERE { 

    # ?country (wdt:P31|wdt:P122)/wdt:P279* wd:Q7269 ;
               wdt:P1082 ?poluation;
               wdt:P571  ?inception ;
                wdt:P140 ?religion.
                
     OPTIONAL{  ?country wdt:P2348 ?period.?period sc:name ?periodname.
     }
                

    # ?country sc:name ?countryname.
    # ?religion sc:name ?religionname.  
     
} 
limit 5
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('countryname', 'Goryeo'), ('poluation', '2100000'), ('periodname', 'Goryeo period'), ('religionname', 'Korean Buddhism')]
# [('countryname', 'Safavid Empire'), ('poluation', '20000000'), ('periodname', 'early modern Iran'), ('religionname', 'Twelvers')]
# [('countryname', 'Safavid Empire'), ('poluation', '20000000'), ('periodname', 'early modern Iran'), ('religionname', 'Islam')]
# [('countryname', 'Roman Catholic Diocese of Bolzano-Brixen'), ('poluation', '525092'), ('religionname', 'Catholicism')]
# [('countryname', 'Kingdom of Dalmatia'), ('poluation', '645666'), ('religionname', 'Catholic Church')]
# 5

# %%
3. Which is or was the country with the highest population?

# %%
# I find all countries and their poluation 
# then i get last listed number of poluation for that country
queryString = """
SELECT DISTINCT  ?countryname  (max(?poluation) as ?lastpoluation )
WHERE { 

    # ?country (wdt:P31|wdt:P122)/wdt:P279* wd:Q7269 ;
               wdt:P1082 ?poluation.

    # ?country sc:name ?countryname.

} 

order by desc(?lastpoluation)
limit 5
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('countryname', 'British Empire'), ('lastpoluation', '680000000')]
# [('countryname', 'Qing dynasty'), ('lastpoluation', '432000000')]
# [('countryname', 'Russian Empire'), ('lastpoluation', '181537800')]
# [('countryname', 'Mongol Empire'), ('lastpoluation', '160000000')]
# [('countryname', 'Mughal Empire'), ('lastpoluation', '150000000')]
# 5

# %%
4. How many countries are or have been monarchies across continents?

# %%
# then i get last listed number of poluation for that country
queryString = """
SELECT DISTINCT  ?continentname  (count(?countryname) as ?howmanycountries )
WHERE { 

    # ?country (wdt:P31|wdt:P122)/wdt:P279* wd:Q7269 ;
               wdt:P30 ?continent.

    # ?continent sc:name ?continentname.
    # ?country sc:name ?countryname.

} 

order by desc(?howmanycountries)

"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('continentname', 'Europe'), ('howmanycountries', '478')]
# [('continentname', 'Asia'), ('howmanycountries', '207')]
# [('continentname', 'Africa'), ('howmanycountries', '72')]
# [('continentname', 'North America'), ('howmanycountries', '41')]
# [('continentname', 'Insular Oceania'), ('howmanycountries', '20')]
# [('continentname', 'Eurasia'), ('howmanycountries', '16')]
# [('continentname', 'Hyboria'), ('howmanycountries', '13')]
# [('continentname', 'South America'), ('howmanycountries', '8')]
# [('continentname', 'The Continent'), ('howmanycountries', '7')]
# [('continentname', 'Americas'), ('howmanycountries', '7')]
# [('continentname', 'Thuria'), ('howmanycountries', '6')]
# [('continentname', 'Central America'), ('howmanycountries', '2')]
# [('continentname', 'Australia'), ('howmanycountries', '2')]
# [('continentname', 'Northern America and Mexico'), ('howmanycountries', '1')]
# [('continentname', 'Antarctica'), ('howmanycountries', '1')]
# [('continentname', 'Caribbean'), ('howmanycountries', '1')]
# 16

# %%
5.1 >>How many sub-types of monarchy exist? << How many instances of exist of each one?

# %%
# find all value for each calsses which are sub class of monarchy
queryString = """
SELECT DISTINCT  ?typename  
WHERE { 

    # ?type wdt:P279 wd:Q7269 .


    # ?type sc:name ?typename.

} 
limit 5


"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('typename', 'patrimonialism')]
# [('typename', 'feudal monarchy')]
# [('typename', 'despotism')]
# [('typename', 'elective monarchy')]
# [('typename', 'hereditary monarchy')]
# 5

# %%
# count the number of type
queryString = """
SELECT DISTINCT  Count(*)  
WHERE { 

    # ?type wdt:P279 wd:Q7269 .


    # ?type sc:name ?typename.

} 
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('callret-0', '26')]
# 1

# %%
5.1 How many sub-types of monarchy exist?  >>How many instances of exist of each one?<<

# %%
# number of instances in each type of monarchy
queryString = """
SELECT DISTINCT  ?typename  (count(?countryname) as ?numberOfInstance)
WHERE { 

    # ?type wdt:P279 wd:Q7269 .
    # ?country (wdt:P31|wdt:P122)/wdt:P279* ?type .

   
    # ?country sc:name ?countryname.
    # ?type sc:name ?typename.

} 

order by desc(?numberOfInstance)
limit 5
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('typename', 'principality'), ('numberOfInstance', '396')]
# [('typename', 'kingdom'), ('numberOfInstance', '231')]
# [('typename', 'constitutional monarchy'), ('numberOfInstance', '213')]
# [('typename', 'duchy'), ('numberOfInstance', '188')]
# [('typename', 'absolute monarchy'), ('numberOfInstance', '170')]
# 5

# %%
5.2 Are there cities that have been capital of multiple kingdoms?

# %%
# I count for each capital, all countries which had common capital and then I just keep capitals which had more than one country
queryString = """
SELECT DISTINCT  ?capitalname  (count(?countryname) AS ?numberOfCountry)
WHERE { 

    # ?country (wdt:P31|wdt:P122)/wdt:P279* wd:Q7269 ;
                wdt:P36 ?capital .

    # ?capital sc:name ?capitalname.
    # ?country sc:name ?countryname.

} 

order by desc(?numberOfCountry >1)
limit 5
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('capitalname', 'Coburg'), ('numberOfCountry', '4')]
# [('capitalname', 'Nassau'), ('numberOfCountry', '2')]
# [('capitalname', 'Kingstown'), ('numberOfCountry', '2')]
# [('capitalname', 'Hilo'), ('numberOfCountry', '2')]
# [('capitalname', 'Pataliputra'), ('numberOfCountry', '2')]
# 5

# %%
5.3 Which are the top-3 monarchies with the earliest inception and still existing?

# %%
# find all monarchies which are not replaced by other monarchies and get their inception date
queryString = """
SELECT distinct ?countryname (?inception)
WHERE { 

    # ?country (wdt:P31|wdt:P122)/wdt:P279* wd:Q7269 ;
               wdt:P571  ?inception .
               
    filter not exists {?country (wdt:P31|wdt:P122)/wdt:P279* wd:Q7269 ;
                                                wdt:P1366 ?replaceby.}
          
   FILTER ( datatype(?inception) = xsd:dateTime) 
   FILTER ( coalesce(xsd:datetime(str(?inception)), '!') != '!')
    # ?country sc:name ?countryname.
} 
order by  (  xsd:dateTime(?inception) )
#limit 30
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('countryname', 'Kushan Empire'), ('inception', '0030-01-01T00:00:00Z')]
# [('countryname', 'Kingdom of Funan'), ('inception', '0068-01-01T00:00:00Z')]
# [('countryname', 'Chen princedom'), ('inception', '0088-01-01T00:00:00Z')]
# [('countryname', 'Champa'), ('inception', '0192-01-01T00:00:00Z')]
# [('countryname', 'Kingdom of Araba'), ('inception', '0200-01-01T00:00:00Z')]
# [('countryname', 'Shule Kingdom'), ('inception', '0200-01-01T00:00:00Z')]
# [('countryname', 'Roman Catholic Diocese of Metz'), ('inception', '0201-01-01T00:00:00Z')]
# [('countryname', 'Ghassanids'), ('inception', '0220-01-01T00:00:00Z')]
# [('countryname', 'Sasanian Empire'), ('inception', '0226-01-01T00:00:00Z')]
# [('countryname', 'Afrighids'), ('inception', '0305-01-01T00:00:00Z')]
# [('countryname', 'Rouran Khaganate'), ('inception', '0330-01-01T00:00:00Z')]
# [('countryname', 'Airgíalla'), ('inception', '0331-01-01T00:00:00Z')]
# [('countryname', 'Kamarupa'), ('inception', '0350-01-01T00:00:00Z')]
# [('countryname', 'Kingdom Saal'), ('inception', '0400-01-01T00:00:00Z')]
# [('countryname', 'Kindah Kingdom'), ('inception', '0400-01-01T00:00:00Z')]
# [('countryname', 'Nobatia'), ('inception', '0400-01-01T00:00:00Z')]
# [('countryname', 'Rhos'), ('inception', '0401-01-01T00:00:00Z')]
# [('countryname', 'Tyrconnell'), ('inception', '0401-01-01T00:00:00Z')]
# [('countryname', 'Kingdom of Dyfed'), ('inception', '0410-01-01T00:00:00Z')]
# [('countryname', 'Kingdom of Strathclyde'), ('inception', '0410-01-01T00:00:00Z')]
# [('countryname', 'Kingdom of the Burgundians'), ('inception', '0411-01-01T00:00:00Z')]
# [('countryname', 'Kingdom of Bernicia'), ('inception', '0420-01-01T00:00:00Z')]
# [('countryname', 'Mauro-Roman kingdom'), ('inception', '0429-01-01T00:00:00Z')]
# [('countryname', 'Kingdom of Kent'), ('inception', '0450-01-01T00:00:00Z')]
# [('countryname', 'Kingdom of Brycheiniog'), ('inception', '0450-01-01T00:00:00Z')]
# [('countryname', 'duchy of Alamannia'), ('inception', '0496-01-01T00:00:00Z')]
# [('countryname', 'Kingdom of Ceredigion'), ('inception', '0500-01-01T00:00:00Z')]
# [('countryname', 'Kingdom of Rheged'), ('inception', '0500-01-01T00:00:00Z')]
# [('countryname', 'Kingdom of Makuria'), ('inception', '0500-01-01T00:00:00Z')]
# [('countryname', 'Frisian Kingdom'), ('inception', '0500-01-01T00:00:00Z')]
# [('countryname', 'Hen Ogledd'), ('inception', '0500-01-01T00:00:00Z')]
# [('countryname', 'Meirionnydd'), ('inception', '0500-01-01T00:00:00Z')]
# [('countryname', "Kingdom Tzu'"), ('inception', '0500-01-01T00:00:00Z')]
# [('countryname', 'Cornouaille'), ('inception', '0500-01-01T00:00:00Z')]
# [('countryname', 'Principality of Chaghaniyan'), ('inception', '0500-01-01T00:00:00Z')]
# [('countryname', 'Kingdom of East Anglia'), ('inception', '0501-01-01T00:00:00Z')]
# [('countryname', 'Kingdom of Mercia'), ('inception', '0527-01-01T00:00:00Z')]
# [('countryname', 'Kingdom of Essex'), ('inception', '0527-01-01T00:00:00Z')]
# [('countryname', 'Duchy of Perugia'), ('inception', '0554-01-01T00:00:00Z')]
# [('countryname', 'Avar Khaganate'), ('inception', '0562-01-01T00:00:00Z')]
# [('countryname', 'Kingdom of the Lombards'), ('inception', '0568-01-01T00:00:00Z')]
# [('countryname', 'duchy of Asti'), ('inception', '0569-01-01T00:00:00Z')]
# [('countryname', 'Duke of Turin'), ('inception', '0569-01-01T00:00:00Z')]
# [('countryname', 'Duchy of Benevento'), ('inception', '0570-01-01T00:00:00Z')]
# [('countryname', 'Duchy of Bergamo'), ('inception', '0570-01-01T00:00:00Z')]
# [('countryname', 'Duchy of Tridentum'), ('inception', '0574-01-01T00:00:00Z')]
# [('countryname', 'Kingdom of Altava'), ('inception', '0578-01-01T00:00:00Z')]
# [('countryname', 'Principate of Iberia'), ('inception', '0588-01-01T00:00:00Z')]
# [('countryname', 'Alodia'), ('inception', '0600-01-01T00:00:00Z')]
# [('countryname', 'Roman Catholic Diocese of Bolzano-Brixen'), ('inception', '0600-01-01T00:00:00Z')]
# [('countryname', 'Kingdom of Rogaland'), ('inception', '0600-01-01T00:00:00Z')]
# [('countryname', 'Wari Empire'), ('inception', '0600-01-01T00:00:00Z')]
# [('countryname', 'Volga Bulgaria'), ('inception', '0601-01-01T00:00:00Z')]
# [('countryname', 'Rutul Federation'), ('inception', '0601-01-01T00:00:00Z')]
# [('countryname', 'Tibetan Empire'), ('inception', '0618-01-01T00:00:00Z')]
# [('countryname', 'Duchy of Thuringia'), ('inception', '0631-01-01T00:00:00Z')]
# [('countryname', 'Kingdom of Nanzhao'), ('inception', '0649-01-01T00:00:00Z')]
# [('countryname', 'Kingdom of Northumbria'), ('inception', '0653-01-01T00:00:00Z')]
# [('countryname', 'Umayyad Caliphate'), ('inception', '0661-01-01T00:00:00Z')]
# [('countryname', 'Sunda Kingdom'), ('inception', '0669-01-01T00:00:00Z')]
# [('countryname', 'Kingdom of Seisyllwg'), ('inception', '0680-01-01T00:00:00Z')]
# [('countryname', 'Ostikanate of Arminiya'), ('inception', '0685-01-01T00:00:00Z')]
# [('countryname', 'Orkdalen Kingdom'), ('inception', '0700-01-01T00:00:00Z')]
# [('countryname', 'duchy of Alsace'), ('inception', '0700-01-01T00:00:00Z')]
# [('countryname', 'Sweden'), ('inception', '0700-01-01T00:00:00Z')]
# [('countryname', 'Kingdom of Sogn'), ('inception', '0700-01-01T00:00:00Z')]
# [('countryname', 'Land'), ('inception', '0700-01-01T00:00:00Z')]
# [('countryname', 'Ranrike'), ('inception', '0700-01-01T00:00:00Z')]
# [('countryname', 'Kingdom of Hadeland'), ('inception', '0700-01-01T00:00:00Z')]
# [('countryname', 'Ringerike'), ('inception', '0700-01-01T00:00:00Z')]
# [('countryname', 'Kingdom of Telemark'), ('inception', '0700-01-01T00:00:00Z')]
# [('countryname', 'Kingdom of Romsdal'), ('inception', '0700-01-01T00:00:00Z')]
# [('countryname', 'Uplands, Norway'), ('inception', '0700-01-01T00:00:00Z')]
# [('countryname', 'Kingdom of Gudbrandsdalen'), ('inception', '0700-01-01T00:00:00Z')]
# [('countryname', 'Kingdom of Voss'), ('inception', '0700-01-01T00:00:00Z')]
# [('countryname', 'Kingdom of Namdalen'), ('inception', '0700-01-01T00:00:00Z')]
# [('countryname', 'Kingdom of Sunnmøre'), ('inception', '0700-01-01T00:00:00Z')]
# [('countryname', 'Kingdom of Solør'), ('inception', '0700-01-01T00:00:00Z')]
# [('countryname', 'Kingdom of Toten'), ('inception', '0700-01-01T00:00:00Z')]
# [('countryname', 'Kingdom of Fjordane'), ('inception', '0700-01-01T00:00:00Z')]
# [('countryname', 'Kingdom of Hordaland'), ('inception', '0700-01-01T00:00:00Z')]
# [('countryname', 'Kingdom of Grenland'), ('inception', '0700-01-01T00:00:00Z')]
# [('countryname', 'Kingdom of Hedmark'), ('inception', '0700-01-01T00:00:00Z')]
# [('countryname', 'Kingdom of Hardanger'), ('inception', '0700-01-01T00:00:00Z')]
# [('countryname', 'duchy of the Ripuarian Franks'), ('inception', '0700-01-01T00:00:00Z')]
# [('countryname', "Rus' Khaganate"), ('inception', '0700-01-01T00:00:00Z')]
# [('countryname', 'Medang Kingdom'), ('inception', '0716-01-01T00:00:00Z')]
# [('countryname', 'Kingdom of Asturias'), ('inception', '0718-01-01T00:00:00Z')]
# [('countryname', "St. Emmeram's Abbey"), ('inception', '0739-01-01T00:00:00Z')]
# [('countryname', 'Uyghur Khaganate'), ('inception', '0744-01-01T00:00:00Z')]
# [('countryname', 'emirate of Córdoba'), ('inception', '0756-01-01T00:00:00Z')]
# [('countryname', 'Principality of Serbia (early medieval)'), ('inception', '0768-01-01T00:00:00Z')]
# [('countryname', 'Rustamid kingdom'), ('inception', '0777-01-01T00:00:00Z')]
# [('countryname', 'Electorate of Mainz'), ('inception', '0780-01-01T00:00:00Z')]
# [('countryname', 'Kingdom of Agder'), ('inception', '0790-01-01T00:00:00Z')]
# [('countryname', 'Danish Realm'), ('inception', '0800-01-01T00:00:00Z')]
# [('countryname', 'Denmark'), ('inception', '0800-01-01T00:00:00Z')]
# [('countryname', 'Kingdom of Nicoya'), ('inception', '0800-01-01T00:00:00Z')]
# [('countryname', 'Shamkhalate of Tarki'), ('inception', '0800-01-01T00:00:00Z')]
# [('countryname', 'Kingdom of Vestmar'), ('inception', '0800-01-01T00:00:00Z')]
# [('countryname', 'Alania'), ('inception', '0801-01-01T00:00:00Z')]
# [('countryname', 'Khmer Empire'), ('inception', '0802-01-01T00:00:00Z')]
# [('countryname', 'Duchy of Saxony'), ('inception', '0804-01-01T00:00:00Z')]
# [('countryname', 'Samanid Empire'), ('inception', '0819-01-01T00:00:00Z')]
# [('countryname', 'Principality of Khachen'), ('inception', '0821-01-01T00:00:00Z')]
# [('countryname', 'Emirate of Sicily'), ('inception', '0831-01-01T00:00:00Z')]
# [('countryname', 'Great Moravia'), ('inception', '0833-01-01T00:00:00Z')]
# [('countryname', 'Duchy of Gaeta'), ('inception', '0839-01-01T00:00:00Z')]
# [('countryname', 'Duchy of Amalfi'), ('inception', '0839-09-09T00:00:00Z')]
# [('countryname', 'Duchy of Aquitaine'), ('inception', '0841-01-01T00:00:00Z')]
# [('countryname', 'Principality of Lower Pannonia'), ('inception', '0846-01-01T00:00:00Z')]
# [('countryname', 'Gansu Uyghur Kingdom'), ('inception', '0848-01-01T00:00:00Z')]
# [('countryname', 'Principality of Salerno'), ('inception', '0851-01-01T00:00:00Z')]
# [('countryname', 'Duklja'), ('inception', '0854-01-01T00:00:00Z')]
# [('countryname', "Kievan Rus'"), ('inception', '0860-01-01T00:00:00Z')]
# [('countryname', 'Bishopric of Worms'), ('inception', '0861-01-01T00:00:00Z')]
# [('countryname', 'Tulunid emirate'), ('inception', '0868-01-01T00:00:00Z')]
# [('countryname', 'Kingdom of Norway (872–1397)'), ('inception', '0872-01-01T00:00:00Z')]
# [('countryname', 'Kldekari'), ('inception', '0876-01-01T00:00:00Z')]
# [('countryname', 'Duchy of Burgundy'), ('inception', '0880-01-01T00:00:00Z')]
# [('countryname', 'Bagratid Armenia'), ('inception', '0885-01-01T00:00:00Z')]
# [('countryname', 'Bishopric of Speyer'), ('inception', '0888-01-01T00:00:00Z')]
# [('countryname', 'Sajids'), ('inception', '0889-01-01T00:00:00Z')]
# [('countryname', 'Pre-modern Hungary'), ('inception', '0895-01-01T00:00:00Z')]
# [('countryname', 'Electorate of Trier'), ('inception', '0898-01-01T00:00:00Z')]
# [('countryname', 'Norway'), ('inception', '0900-01-01T00:00:00Z')]
# [('countryname', 'Principality of Polotsk'), ('inception', '0900-01-01T00:00:00Z')]
# [('countryname', 'Kingdom of the Isles'), ('inception', '0900-01-01T00:00:00Z')]
# [('countryname', 'Principality of Capua'), ('inception', '0900-01-01T00:00:00Z')]
# [('countryname', 'Zagwe dynasty'), ('inception', '0900-01-01T00:00:00Z')]
# [('countryname', 'The Moravian Principality'), ('inception', '0900-01-01T00:00:00Z')]
# [('countryname', 'Tabasaran Principality'), ('inception', '0901-01-01T00:00:00Z')]
# [('countryname', 'Sultanate of Mogadishu'), ('inception', '0901-01-01T00:00:00Z')]
# [('countryname', 'Dachanghe'), ('inception', '0902-01-01T00:00:00Z')]
# [('countryname', 'Duchy of Franconia'), ('inception', '0906-01-01T00:00:00Z')]
# [('countryname', 'Duchy of Bavaria'), ('inception', '0907-01-01T00:00:00Z')]
# [('countryname', 'Kingdom of León'), ('inception', '0910-01-01T00:00:00Z')]
# [('countryname', 'Duchy of Swabia'), ('inception', '0917-01-01T00:00:00Z')]
# [('countryname', 'Kingdom of Deheubarth'), ('inception', '0920-01-01T00:00:00Z')]
# [('countryname', 'Kingdom of Najera'), ('inception', '0923-01-01T00:00:00Z')]
# [('countryname', 'Banu Ilyas'), ('inception', '0932-01-01T00:00:00Z')]
# [('countryname', 'Buyid dynasty'), ('inception', '0934-01-01T00:00:00Z')]
# [('countryname', 'Duchy of Brittany'), ('inception', '0939-01-01T00:00:00Z')]
# [('countryname', 'Ngô Dynasty'), ('inception', '0939-01-01T00:00:00Z')]
# [('countryname', 'Sallarid dynasty'), ('inception', '0941-01-01T00:00:00Z')]
# [('countryname', 'Tuʻi Tonga Empire'), ('inception', '0951-01-01T00:00:00Z')]
# [('countryname', 'Electorate of Cologne'), ('inception', '0953-01-01T00:00:00Z')]
# [('countryname', 'Lower Lotharingia'), ('inception', '0959-01-01T00:00:00Z')]
# [('countryname', 'Duchy of Lorraine'), ('inception', '0959-01-01T00:00:00Z')]
# [('countryname', 'Duchy of Poland'), ('inception', '0960-01-01T00:00:00Z')]
# [('countryname', 'Civitas Schinesghe'), ('inception', '0960-01-01T00:00:00Z')]
# [('countryname', 'Civitas Schinesghe'), ('inception', '0962-01-01T00:00:00Z')]
# [('countryname', 'County of Luxembourg'), ('inception', '0963-01-01T00:00:00Z')]
# [('countryname', 'Margraviate of Meissen'), ('inception', '0965-01-01T00:00:00Z')]
# [('countryname', 'Duchy of Poland'), ('inception', '0966-01-01T00:00:00Z')]
# [('countryname', 'Bishopric of Naumburg-Zeitz'), ('inception', '0968-01-07T00:00:00Z')]
# [('countryname', 'Zirid dynasty'), ('inception', '0972-01-01T00:00:00Z')]
# [('countryname', 'Duchy of Carinthia'), ('inception', '0976-01-01T00:00:00Z')]
# [('countryname', 'Prince-Bishopric of Strasbourg'), ('inception', '0982-01-01T00:00:00Z')]
# [('countryname', 'Kingdom of Syunik'), ('inception', '0987-01-01T00:00:00Z')]
# [('countryname', 'Principality of Chernigov'), ('inception', '0988-01-01T00:00:00Z')]
# [('countryname', 'Kingdom of Hungary in the Middle Ages'), ('inception', '1000-01-01T00:00:00Z')]
# [('countryname', 'Kingdom of Vestfold'), ('inception', '1000-01-01T00:00:00Z')]
# [('countryname', 'Vingulmark'), ('inception', '1000-01-01T00:00:00Z')]
# [('countryname', 'Kingdom of Pacaca'), ('inception', '1000-01-01T00:00:00Z')]
# [('countryname', 'Kingdom of Artsakh'), ('inception', '1000-01-01T00:00:00Z')]
# [('countryname', 'Butuan (historical polity)'), ('inception', '1001-01-01T00:00:00Z')]
# [('countryname', 'Duchy of Jülich'), ('inception', '1003-01-01T00:00:00Z')]
# [('countryname', 'Bishopric of Merseburg'), ('inception', '1004-01-01T00:00:00Z')]
# [('countryname', 'Prince-Bishopric of Bamberg'), ('inception', '1007-01-01T00:00:00Z')]
# [('countryname', 'Kingdom of Georgia'), ('inception', '1008-01-01T00:00:00Z')]
# [('countryname', 'Kakuyids'), ('inception', '1008-01-01T00:00:00Z')]
# [('countryname', 'Signoria di Correggio'), ('inception', '1009-01-01T00:00:00Z')]
# [('countryname', 'Taifa of Valencia'), ('inception', '1010-01-01T00:00:00Z')]
# [('countryname', 'Taifa of Toledo'), ('inception', '1010-01-01T00:00:00Z')]
# [('countryname', 'Ellwangen Abbey'), ('inception', '1011-01-01T00:00:00Z')]
# [('countryname', 'Ghurid Dynasty'), ('inception', '1011-01-01T00:00:00Z')]
# [('countryname', 'Taifa of Carmona'), ('inception', '1013-01-01T00:00:00Z')]
# [('countryname', 'Hammadid dynasty'), ('inception', '1014-01-01T00:00:00Z')]
# [('countryname', 'Taifa of Zaragoza'), ('inception', '1018-01-01T00:00:00Z')]
# [('countryname', 'Bishopric of Trent'), ('inception', '1027-01-01T00:00:00Z')]
# [('countryname', 'Bishopric of Brixen'), ('inception', '1027-01-01T00:00:00Z')]
# [('countryname', 'Duchy of Bar'), ('inception', '1033-01-01T00:00:00Z')]
# [('countryname', 'Principality of Neuchâtel'), ('inception', '1034-01-01T00:00:00Z')]
# [('countryname', 'Kingdom of Castile'), ('inception', '1035-01-01T00:00:00Z')]
# [('countryname', 'Seljuk Empire'), ('inception', '1037-01-01T00:00:00Z')]
# [('countryname', 'Taifa of Ronda'), ('inception', '1039-01-01T00:00:00Z')]
# [('countryname', 'County of Apulia'), ('inception', '1042-01-01T00:00:00Z')]
# [('countryname', 'County of Montbéliard'), ('inception', '1042-01-01T00:00:00Z')]
# [('countryname', 'Duchy of Apulia and Calabria'), ('inception', '1059-01-01T00:00:00Z')]
# [('countryname', 'Kingdom of Morgannwg'), ('inception', '1063-01-01T00:00:00Z')]
# [('countryname', 'Duchy of Limburg'), ('inception', '1065-01-01T00:00:00Z')]
# [('countryname', 'Kingdom of Dalmatia'), ('inception', '1069-01-01T00:00:00Z')]
# [('countryname', 'County of Sicily'), ('inception', '1071-01-01T00:00:00Z')]
# [('countryname', 'Kingdom of Mapungubwe'), ('inception', '1075-01-01T00:00:00Z')]
# [('countryname', 'Sultanate of Rum'), ('inception', '1077-01-01T00:00:00Z')]
# [('countryname', 'Zvenyhorod Principality'), ('inception', '1084-01-01T00:00:00Z')]
# [('countryname', 'Electoral Palatinate'), ('inception', '1085-01-01T00:00:00Z')]
# [('countryname', 'Wied'), ('inception', '1093-01-01T00:00:00Z')]
# [('countryname', 'Guelders'), ('inception', '1096-01-01T00:00:00Z')]
# [('countryname', 'Principality of Ryazan'), ('inception', '1097-01-01T00:00:00Z')]
# [('countryname', 'Principality of Novgorod-Seversk'), ('inception', '1097-01-01T00:00:00Z')]
# [('countryname', 'County of Edessa'), ('inception', '1098-01-01T00:00:00Z')]
# [('countryname', 'Principality of Galilee'), ('inception', '1099-01-01T00:00:00Z')]
# [('countryname', 'Principality of Vyshgorod'), ('inception', '1100-01-01T00:00:00Z')]
# [('countryname', 'Principality of Vilnius'), ('inception', '1100-01-01T00:00:00Z')]
# [('countryname', 'Daju kingdom'), ('inception', '1100-01-01T00:00:00Z')]
# [('countryname', 'Damot'), ('inception', '1100-01-01T00:00:00Z')]
# [('countryname', 'Duchy of Berg'), ('inception', '1101-01-01T00:00:00Z')]
# [('countryname', 'Principality of Vitebsk'), ('inception', '1101-01-01T00:00:00Z')]
# [('countryname', 'Principality of Minsk'), ('inception', '1101-01-01T00:00:00Z')]
# [('countryname', 'Croatia in personal union with Hungary'), ('inception', '1102-01-01T00:00:00Z')]
# [('countryname', 'Principality of Transylvania'), ('inception', '1111-01-01T00:00:00Z')]
# [('countryname', 'Principality of Goroden'), ('inception', '1116-01-01T00:00:00Z')]
# [('countryname', 'Kingdom of Desmond'), ('inception', '1118-01-01T00:00:00Z')]
# [('countryname', 'Khamag Mongol'), ('inception', '1120-01-01T00:00:00Z')]
# [('countryname', 'Duchy of Pomerania'), ('inception', '1121-01-01T00:00:00Z')]
# [('countryname', 'Lippe'), ('inception', '1123-01-01T00:00:00Z')]
# [('countryname', 'Grand Duchy of Vladimir'), ('inception', '1125-01-01T00:00:00Z')]
# [('countryname', 'Zengid dynasty'), ('inception', '1127-01-01T00:00:00Z')]
# [('countryname', 'Principality of Murom'), ('inception', '1127-01-01T00:00:00Z')]
# [('countryname', 'Kingdom of Sicily'), ('inception', '1130-01-01T00:00:00Z')]
# [('countryname', 'Principality of Kyiv'), ('inception', '1132-01-01T00:00:00Z')]
# [('countryname', 'Contship of Heiligenberg'), ('inception', '1135-01-01T00:00:00Z')]
# [('countryname', 'Principality of Salm'), ('inception', '1135-01-01T00:00:00Z')]
# [('countryname', 'Seniorate Province'), ('inception', '1138-01-01T00:00:00Z')]
# [('countryname', 'Duchy of Masovia'), ('inception', '1138-01-01T00:00:00Z')]
# [('countryname', 'Duchy of Silesia'), ('inception', '1138-01-01T00:00:00Z')]
# [('countryname', 'County of Tyrol'), ('inception', '1140-01-01T00:00:00Z')]
# [('countryname', 'Kingdom of Africa'), ('inception', '1146-01-01T00:00:00Z')]
# [('countryname', 'Ghurid Empire'), ('inception', '1148-01-01T00:00:00Z')]
# [('countryname', 'Duchy of Merania'), ('inception', '1153-01-01T00:00:00Z')]
# [('countryname', 'Angevin Empire'), ('inception', '1154-01-01T00:00:00Z')]
# [('countryname', 'Duchy of Austria'), ('inception', '1156-01-01T00:00:00Z')]
# [('countryname', 'Principality of Lutsk'), ('inception', '1157-01-01T00:00:00Z')]
# [('countryname', 'Bishopric of Lübeck'), ('inception', '1160-01-01T00:00:00Z')]
# [('countryname', 'County of Mark'), ('inception', '1160-01-01T00:00:00Z')]
# [('countryname', 'Principality of Orange'), ('inception', '1163-01-01T00:00:00Z')]
# [('countryname', 'Bishopric of Brandenburg'), ('inception', '1165-01-01T00:00:00Z')]
# [('countryname', 'Bishopric of Würzburg'), ('inception', '1168-01-01T00:00:00Z')]
# [('countryname', 'Principality of Rügen'), ('inception', '1168-01-01T00:00:00Z')]
# [('countryname', 'Ayyubid dynasty'), ('inception', '1171-01-01T00:00:00Z')]
# [('countryname', 'Duchy of Opole'), ('inception', '1172-01-01T00:00:00Z')]
# [('countryname', 'Duchy of Racibórz'), ('inception', '1172-01-01T00:00:00Z')]
# [('countryname', 'Duchy of Wroclaw'), ('inception', '1173-01-01T00:00:00Z')]
# [('countryname', 'Pinsk principality'), ('inception', '1174-01-01T00:00:00Z')]
# [('countryname', 'Duchy of Głogów'), ('inception', '1177-01-01T00:00:00Z')]
# [('countryname', 'Archbishopric of Magdeburg'), ('inception', '1180-01-01T00:00:00Z')]
# [('countryname', 'Duchy of Styria'), ('inception', '1180-01-01T00:00:00Z')]
# [('countryname', 'Bishopric of Minden'), ('inception', '1180-01-01T00:00:00Z')]
# [('countryname', 'Waldeck'), ('inception', '1180-01-01T00:00:00Z')]
# [('countryname', 'Archbishopric of Bremen'), ('inception', '1180-01-01T00:00:00Z')]
# [('countryname', 'Prince-Bishopric of Münster'), ('inception', '1180-01-01T00:00:00Z')]
# [('countryname', 'Bishopric of Halberstadt'), ('inception', '1180-01-01T00:00:00Z')]
# [('countryname', 'Principality of Koknese'), ('inception', '1180-01-01T00:00:00Z')]
# [('countryname', 'Margraviate of Moravia'), ('inception', '1182-01-01T00:00:00Z')]
# [('countryname', 'Principality of Mingrelia'), ('inception', '1184-01-01T00:00:00Z')]
# [('countryname', 'Archbishop of Riga'), ('inception', '1186-01-01T00:00:00Z')]
# [('countryname', '4000 Parvat Kingdom'), ('inception', '1189-01-01T00:00:00Z')]
# [('countryname', 'Takam Kingdom'), ('inception', '1189-01-01T00:00:00Z')]
# [('countryname', 'Principality of Jersika'), ('inception', '1190-01-01T00:00:00Z')]
# [('countryname', 'Principality of Arbanon'), ('inception', '1190-01-01T00:00:00Z')]
# [('countryname', 'Kingdom of Galicia–Volhynia'), ('inception', '1199-01-01T00:00:00Z')]
# [('countryname', 'Armenian Kingdom of Cilicia'), ('inception', '1199-01-01T00:00:00Z')]
# [('countryname', 'Aymara kingdoms'), ('inception', '1200-01-01T00:00:00Z')]
# [('countryname', 'Zakarid Armenia'), ('inception', '1201-01-01T00:00:00Z')]
# [('countryname', 'Bishopric of Regensburg'), ('inception', '1201-01-01T00:00:00Z')]
# [('countryname', 'Duchy of Opole and Racibórz'), ('inception', '1202-01-01T00:00:00Z')]
# [('countryname', 'Latin Empire'), ('inception', '1204-01-01T00:00:00Z')]
# [('countryname', 'Kingdom of Thessalonica'), ('inception', '1204-01-01T00:00:00Z')]
# [('countryname', 'Empire of Nicaea'), ('inception', '1204-01-01T00:00:00Z')]
# [('countryname', 'Lordship of Demotika'), ('inception', '1204-01-01T00:00:00Z')]
# [('countryname', 'Delhi Sultanate'), ('inception', '1206-01-01T00:00:00Z')]
# [('countryname', 'Duchy of the Archipelago'), ('inception', '1207-01-01T00:00:00Z')]
# [('countryname', 'Margraviate of Baden-Hachberg'), ('inception', '1212-01-01T00:00:00Z')]
# [('countryname', 'Duchy of Urbino'), ('inception', '1213-01-01T00:00:00Z')]
# [('countryname', 'Shan States'), ('inception', '1215-01-01T00:00:00Z')]
# [('countryname', 'Kingdom of Serbia'), ('inception', '1217-01-01T00:00:00Z')]
# [('countryname', 'Principality of Fürstenberg'), ('inception', '1218-01-01T00:00:00Z')]
# [('countryname', 'Warsangali Sultanate'), ('inception', '1218-01-01T00:00:00Z')]
# [('countryname', 'Principality of Yaroslavl'), ('inception', '1218-01-01T00:00:00Z')]
# [('countryname', 'Amt der Veste'), ('inception', '1219-01-01T00:00:00Z')]
# [('countryname', 'Empire of Thessalonica'), ('inception', '1224-01-01T00:00:00Z')]
# [('countryname', 'Chagatai Khanate'), ('inception', '1225-01-01T00:00:00Z')]
# [('countryname', 'Prince-Bishopric of Osnabrück'), ('inception', '1225-01-01T00:00:00Z')]
# [('countryname', 'Ahom Kingdom'), ('inception', '1228-01-01T00:00:00Z')]
# [('countryname', 'Taifa of Menorca'), ('inception', '1228-01-01T00:00:00Z')]
# [('countryname', 'Bishopric of Ösel-Wiek'), ('inception', '1228-01-01T00:00:00Z')]
# [('countryname', 'Hafsid dynasty'), ('inception', '1229-01-01T00:00:00Z')]
# [('countryname', 'Duchy of Łęczyca'), ('inception', '1231-01-01T00:00:00Z')]
# [('countryname', 'Bishopric of Courland'), ('inception', '1234-01-01T00:00:00Z')]
# [('countryname', 'Duchy of Brunswick-Lüneburg'), ('inception', '1235-01-01T00:00:00Z')]
# [('countryname', 'Bishopric of Hildesheim'), ('inception', '1235-01-01T00:00:00Z')]
# [('countryname', 'Kingdom of Tlemcen'), ('inception', '1235-01-01T00:00:00Z')]
# [('countryname', 'Principality Werle'), ('inception', '1235-01-01T00:00:00Z')]
# [('countryname', 'Grand Duchy of Lithuania'), ('inception', '1236-01-01T00:00:00Z')]
# [('countryname', 'Bishopric of Ratzeburg'), ('inception', '1236-01-01T00:00:00Z')]
# [('countryname', 'Thailand'), ('inception', '1238-01-01T00:00:00Z')]
# [('countryname', 'Principality of Beloozero'), ('inception', '1238-01-01T00:00:00Z')]
# [('countryname', 'Emirate of Granada'), ('inception', '1238-01-01T00:00:00Z')]
# [('countryname', 'Taifa of Orihuela'), ('inception', '1239-01-01T00:00:00Z')]
# [('countryname', 'Kingdom of the Algarve'), ('inception', '1242-01-01T00:00:00Z')]
# [('countryname', 'Prince-Bishopric of Warmia'), ('inception', '1243-01-01T00:00:00Z')]
# [('countryname', 'Golden Horde'), ('inception', '1243-01-01T00:00:00Z')]
# [('countryname', 'Kartids'), ('inception', '1244-01-01T00:00:00Z')]
# [('countryname', 'Kingdom of Jaén'), ('inception', '1246-01-01T00:00:00Z')]
# [('countryname', 'Principality of Tver'), ('inception', '1247-01-01T00:00:00Z')]
# [('countryname', 'Duchy of Legnica'), ('inception', '1248-01-01T00:00:00Z')]
# [('countryname', 'Mamluk Sultanate'), ('inception', '1250-01-01T00:00:00Z')]
# [('countryname', 'Principality of Anhalt-Zerbst'), ('inception', '1252-01-01T00:00:00Z')]
# [('countryname', 'Duchy of Lower Bavaria'), ('inception', '1255-01-01T00:00:00Z')]
# [('countryname', 'Ilkhanate'), ('inception', '1256-01-01T00:00:00Z')]
# [('countryname', 'Ternate Sultanate'), ('inception', '1257-01-01T00:00:00Z')]
# [('countryname', 'Kingdom of Murcia'), ('inception', '1258-01-01T00:00:00Z')]
# [('countryname', 'Menteşe'), ('inception', '1261-01-01T00:00:00Z')]
# [('countryname', 'Duchy of Ferrara'), ('inception', '1264-01-01T00:00:00Z')]
# [('countryname', 'Lordship of the Isles'), ('inception', '1266-01-01T00:00:00Z')]
# [('countryname', 'Pasai'), ('inception', '1267-01-01T00:00:00Z')]
# [('countryname', 'Duchy of Troppau'), ('inception', '1269-01-01T00:00:00Z')]
# [('countryname', 'Principality of Brunswick-Wolfenbüttel'), ('inception', '1269-01-01T00:00:00Z')]
# [('countryname', 'Tibet under Yuan administrative rule'), ('inception', '1270-01-01T00:00:00Z')]
# [('countryname', 'Duchy of Mantua'), ('inception', '1273-01-01T00:00:00Z')]
# [('countryname', 'Duchy of Żagań'), ('inception', '1274-01-01T00:00:00Z')]
# [('countryname', 'Archbishopric of Salzburg'), ('inception', '1278-01-01T00:00:00Z')]
# [('countryname', 'Andorra'), ('inception', '1278-01-01T00:00:00Z')]
# [('countryname', 'Principality of Göttingen'), ('inception', '1279-01-01T00:00:00Z')]
# [('countryname', 'Prince-Bishopric of Paderborn'), ('inception', '1281-01-01T00:00:00Z')]
# [('countryname', 'Duchy of Löwenberg'), ('inception', '1281-01-01T00:00:00Z')]
# [('countryname', 'Duchy of Teschen'), ('inception', '1281-01-01T00:00:00Z')]
# [('countryname', 'Duchy of Bytom'), ('inception', '1281-01-01T00:00:00Z')]
# [('countryname', 'Realm of Stefan Dragutin'), ('inception', '1282-01-01T00:00:00Z')]
# [('countryname', 'Kingdom of Naples'), ('inception', '1282-04-06T00:00:00Z')]
# [('countryname', 'Eshrefids'), ('inception', '1284-01-01T00:00:00Z')]
# [('countryname', 'Ifat Sultanate'), ('inception', '1285-01-01T00:00:00Z')]
# [('countryname', 'Hanthawaddy Kingdom'), ('inception', '1287-01-01T00:00:00Z')]
# [('countryname', 'Duchy of Nysa'), ('inception', '1290-01-01T00:00:00Z')]
# [('countryname', 'Beylik of Isfendiyar'), ('inception', '1292-01-01T00:00:00Z')]
# [('countryname', 'Prince-Bishopric of Freising'), ('inception', '1294-01-01T00:00:00Z')]
# [('countryname', "St. Emmeram's Abbey"), ('inception', '1295-01-01T00:00:00Z')]
# [('countryname', 'Saxe-Lauenburg'), ('inception', '1296-01-01T00:00:00Z')]
# [('countryname', 'Duchy of Saxe-Wittenberg'), ('inception', '1296-01-01T00:00:00Z')]
# [('countryname', 'Beylik of Karasi'), ('inception', '1297-01-01T00:00:00Z')]
# [('countryname', 'Monaco'), ('inception', '1297-01-15T00:00:00Z')]
# [('countryname', 'Hadiya Kingdom'), ('inception', '1300-01-01T00:00:00Z')]
# [('countryname', 'Sultanate of Maguindanao'), ('inception', '1300-01-01T00:00:00Z')]
# [('countryname', 'Nassau-Siegen'), ('inception', '1303-01-01T00:00:00Z')]
# [('countryname', 'Bishopric of Eichstätt'), ('inception', '1305-01-01T00:00:00Z')]
# [('countryname', 'Margraviate Hachberg-Sausenberg'), ('inception', '1306-01-01T00:00:00Z')]
# [('countryname', 'Duchy of Mirandola'), ('inception', '1310-01-01T00:00:00Z')]
# [('countryname', 'Duchy of Brzeg'), ('inception', '1311-01-01T00:00:00Z')]
# [('countryname', 'Beylik of Saruhan'), ('inception', '1313-01-01T00:00:00Z')]
# [('countryname', 'Duchy of Oels'), ('inception', '1313-01-01T00:00:00Z')]
# [('countryname', 'Chūzan'), ('inception', '1314-01-01T00:00:00Z')]
# [('countryname', 'Duchy of Oświęcim'), ('inception', '1315-01-01T00:00:00Z')]
# [('countryname', 'Duchy of Prudnik'), ('inception', '1318-01-01T00:00:00Z')]
# [('countryname', 'United Kingdom of Poland'), ('inception', '1320-01-28T00:00:00Z')]
# [('countryname', 'Duchy of Münsterberg'), ('inception', '1321-01-01T00:00:00Z')]
# [('countryname', 'Despotate of Dobruja'), ('inception', '1322-01-01T00:00:00Z')]
# [('countryname', 'Sarbadars'), ('inception', '1337-01-01T00:00:00Z')]
# [('countryname', 'Duchy of Cornwall'), ('inception', '1337-01-01T00:00:00Z')]
# [('countryname', 'Principality of Valona'), ('inception', '1346-01-01T00:00:00Z')]
# [('countryname', 'Serbian Empire'), ('inception', '1346-04-24T00:00:00Z')]
# [('countryname', 'Moghulistan'), ('inception', '1347-01-01T00:00:00Z')]
# [('countryname', 'Ayutthaya Kingdom'), ('inception', '1350-01-01T00:00:00Z')]
# [('countryname', 'Kingdom of Sine'), ('inception', '1350-01-01T00:00:00Z')]
# [('countryname', 'Duchy of Gerona'), ('inception', '1351-01-01T00:00:00Z')]
# [('countryname', 'Duchy of Lancaster'), ('inception', '1351-01-01T00:00:00Z')]
# [('countryname', 'Sultanate of Bengal'), ('inception', '1352-01-01T00:00:00Z')]
# [('countryname', 'Mecklenburg-Stargard'), ('inception', '1352-12-03T00:00:00Z')]
# [('countryname', 'Bavaria-Straubing'), ('inception', '1353-01-01T00:00:00Z')]
# [('countryname', 'Bavaria-Landshut'), ('inception', '1353-01-01T00:00:00Z')]
# [('countryname', 'Phagmodrupa Dynasty'), ('inception', '1354-01-01T00:00:00Z')]
# [('countryname', 'Lan Xang'), ('inception', '1354-01-01T00:00:00Z')]
# [('countryname', 'Electorate of Saxony'), ('inception', '1356-01-01T00:00:00Z')]
# [('countryname', 'Archduchy of Austria'), ('inception', '1358-01-01T00:00:00Z')]
# [('countryname', 'Duchy of Podolia'), ('inception', '1363-01-01T00:00:00Z')]
# [('countryname', 'Duchy of Carniola'), ('inception', '1364-01-01T00:00:00Z')]
# [('countryname', 'Bruneian Empire'), ('inception', '1368-01-01T00:00:00Z')]
# [('countryname', 'Timurid Empire'), ('inception', '1370-01-01T00:00:00Z')]
# [('countryname', 'Lordship of Prilep'), ('inception', '1371-01-01T00:00:00Z')]
# [('countryname', 'Duchy of Krnov'), ('inception', '1377-01-01T00:00:00Z')]
# [('countryname', 'Ag Qoyunlu Tribe'), ('inception', '1378-01-01T00:00:00Z')]
# [('countryname', 'Principality of Gjirokastër'), ('inception', '1386-01-01T00:00:00Z')]
# [('countryname', 'Principality of Dukagjini'), ('inception', '1387-01-01T00:00:00Z')]
# [('countryname', 'Duchy of Montblanc'), ('inception', '1387-01-01T00:00:00Z')]
# [('countryname', 'Principality of Kastrioti'), ('inception', '1389-01-01T00:00:00Z')]
# [('countryname', 'Bavaria-Munich'), ('inception', '1392-01-01T00:00:00Z')]
# [('countryname', 'Bavaria-Ingolstadt'), ('inception', '1392-01-01T00:00:00Z')]
# [('countryname', 'Principality of Masserano'), ('inception', '1394-01-01T00:00:00Z')]
# [('countryname', 'Kingdom of Kongo'), ('inception', '1395-01-01T00:00:00Z')]
# [('countryname', 'Duchy of Milan'), ('inception', '1395-05-19T00:00:00Z')]
# [('countryname', 'Anhalt-Köthen'), ('inception', '1396-01-01T00:00:00Z')]
# [('countryname', 'Anhalt-Dessau'), ('inception', '1396-01-01T00:00:00Z')]
# [('countryname', 'Kalmar Union'), ('inception', '1397-01-01T00:00:00Z')]
# [('countryname', 'Principality of Ansbach'), ('inception', '1398-01-01T00:00:00Z')]
# [('countryname', 'Principality of Bayreuth'), ('inception', '1398-01-01T00:00:00Z')]
# [('countryname', 'Principality of Bayreuth'), ('inception', '1398-01-29T00:00:00Z')]
# [('countryname', 'Jaunpur Sultanate'), ('inception', '1399-01-01T00:00:00Z')]
# [('countryname', 'Malacca sultanate'), ('inception', '1400-01-01T00:00:00Z')]
# [('countryname', 'Krevsk Duchy'), ('inception', '1400-01-01T00:00:00Z')]
# [('countryname', 'principality of Kodа'), ('inception', '1400-01-01T00:00:00Z')]
# [('countryname', 'Ustuni'), ('inception', '1400-01-01T00:00:00Z')]
# [('countryname', 'Principality of Hakkâri'), ('inception', '1400-01-01T00:00:00Z')]
# [('countryname', 'Sultanate of Sulu'), ('inception', '1405-01-01T00:00:00Z')]
# [('countryname', 'Luyag na Kaboloan'), ('inception', '1406-01-01T00:00:00Z')]
# [('countryname', 'Gujarat Sultanate'), ('inception', '1407-01-01T00:00:00Z')]
# [('countryname', 'Palatinate-Simmern and Zweibrücken'), ('inception', '1410-01-01T00:00:00Z')]
# [('countryname', 'Adal Sultanate'), ('inception', '1415-01-01T00:00:00Z')]
# [('countryname', 'Duchy of Savoy'), ('inception', '1416-01-01T00:00:00Z')]
# [('countryname', 'Duchy of Głogówek and Prudnik'), ('inception', '1420-01-01T00:00:00Z')]
# [('countryname', 'Duchy of Berg'), ('inception', '1423-01-01T00:00:00Z')]
# [('countryname', 'Principality of Debdou'), ('inception', '1430-01-01T00:00:00Z')]
# [('countryname', 'Inca Empire'), ('inception', '1438-01-01T00:00:00Z')]
# [('countryname', 'Crimean Khanate'), ('inception', '1441-01-01T00:00:00Z')]
# [('countryname', 'Duchy of Bragança'), ('inception', '1442-01-01T00:00:00Z')]
# [('countryname', 'Duchy of Sora'), ('inception', '1443-01-01T00:00:00Z')]
# [('countryname', 'Palatinate-Zweibrücken'), ('inception', '1444-01-01T00:00:00Z')]
# [('countryname', 'Duchy of Zator'), ('inception', '1445-01-01T00:00:00Z')]
# [('countryname', 'Sheikhdom of Diriyah'), ('inception', '1446-01-01T00:00:00Z')]
# [('countryname', 'Kingdom of Butua'), ('inception', '1450-01-01T00:00:00Z')]
# [('countryname', 'Rajahnate of Cebu'), ('inception', '1450-01-01T00:00:00Z')]
# [('countryname', 'Principality of Krk'), ('inception', '1451-01-01T00:00:00Z')]
# [('countryname', 'Landgraviate of Hesse-Marburg'), ('inception', '1458-01-01T00:00:00Z')]
# [('countryname', 'Belyov Principality'), ('inception', '1460-01-01T00:00:00Z')]
# [('countryname', 'Principality of Svaneti'), ('inception', '1463-01-01T00:00:00Z')]
# [('countryname', 'County of East Frisia'), ('inception', '1464-01-01T00:00:00Z')]
# [('countryname', 'Principality of Mindelheim'), ('inception', '1467-01-01T00:00:00Z')]
# [('countryname', 'Spain'), ('inception', '1479-01-01T00:00:00Z')]
# [('countryname', 'Anjou'), ('inception', '1482-01-01T00:00:00Z')]
# [('countryname', 'Taungoo Dynasty'), ('inception', '1485-01-01T00:00:00Z')]
# [('countryname', 'Dukedom of Aliaga y Castellot'), ('inception', '1487-10-19T00:00:00Z')]
# [('countryname', 'Principality of Guria'), ('inception', '1490-01-01T00:00:00Z')]
# [('countryname', 'Shilluk Kingdom'), ('inception', '1490-01-01T00:00:00Z')]
# [('countryname', 'Principality of Calenberg'), ('inception', '1494-01-01T00:00:00Z')]
# [('countryname', 'Saloum'), ('inception', '1494-01-01T00:00:00Z')]
# [('countryname', 'Aceh Sultanate'), ('inception', '1496-01-01T00:00:00Z')]
# [('countryname', 'Principality of Pavia'), ('inception', '1499-01-01T00:00:00Z')]
# [('countryname', 'Colonial Brazil'), ('inception', '1500-01-01T00:00:00Z')]
# [('countryname', 'Wajo Kingdom'), ('inception', '1500-01-01T00:00:00Z')]
# [('countryname', 'Kingdom of Banggai'), ('inception', '1500-01-01T00:00:00Z')]
# [('countryname', 'Melikdom of Kashatagh'), ('inception', '1500-01-01T00:00:00Z')]
# [('countryname', 'Waldamt Sebaldi'), ('inception', '1500-01-01T00:00:00Z')]
# [('countryname', 'Waldamt Laurenzi'), ('inception', '1500-01-01T00:00:00Z')]
# [('countryname', 'Safavid Empire'), ('inception', '1501-01-01T00:00:00Z')]
# [('countryname', 'Palatinate-Neuburg'), ('inception', '1505-01-01T00:00:00Z')]
# [('countryname', 'Kingdom of Ait Abbas'), ('inception', '1510-01-01T00:00:00Z')]
# [('countryname', 'Kingdom of Kuku'), ('inception', '1510-01-01T00:00:00Z')]
# [('countryname', 'First Toungoo Empire'), ('inception', '1510-10-26T00:00:00Z')]
# [('countryname', 'Khanate of Khiva'), ('inception', '1511-01-01T00:00:00Z')]
# [('countryname', 'Kingdom of Baguirmi'), ('inception', '1513-01-01T00:00:00Z')]
# [('countryname', 'Margraviate of Baden-Baden'), ('inception', '1515-01-01T00:00:00Z')]
# [('countryname', 'Habsburg Spain'), ('inception', '1516-01-01T00:00:00Z')]
# [('countryname', 'Egypt Eyalet'), ('inception', '1517-01-01T00:00:00Z')]
# [('countryname', 'Duchy of Pless'), ('inception', '1517-01-01T00:00:00Z')]
# [('countryname', 'Golconda Sultanate'), ('inception', '1518-01-01T00:00:00Z')]
# [('countryname', 'Qutb Shahi dynasty'), ('inception', '1518-01-01T00:00:00Z')]
# [('countryname', 'Pflegamt Wildenfels'), ('inception', '1518-01-01T00:00:00Z')]
# [('countryname', 'Mecklenburg-Güstrow'), ('inception', '1520-01-01T00:00:00Z')]
# [('countryname', 'Denmark-Norway'), ('inception', '1524-01-01T00:00:00Z')]
# [('countryname', 'Duchy of Prussia'), ('inception', '1525-01-01T00:00:00Z')]
# [('countryname', 'Mughal Empire'), ('inception', '1526-01-01T00:00:00Z')]
# [('countryname', 'Habsburg Monarchy'), ('inception', '1526-09-08T00:00:00Z')]
# [('countryname', 'Kingdom of Croatia'), ('inception', '1527-01-01T00:00:00Z')]
# [('countryname', 'Syrmian Duchy of Radoslav Čelnik'), ('inception', '1527-01-01T00:00:00Z')]
# [('countryname', 'Soran Emirate'), ('inception', '1530-01-01T00:00:00Z')]
# [('countryname', 'Duchy of Florence'), ('inception', '1532-01-01T00:00:00Z')]
# [('countryname', 'captaincy of Brazil'), ('inception', '1534-01-01T00:00:00Z')]
# [('countryname', 'New France'), ('inception', '1534-01-01T00:00:00Z')]
# [('countryname', 'Principality of Anhalt-Plötzkau'), ('inception', '1544-01-01T00:00:00Z')]
# [('countryname', 'Duchy of Parma'), ('inception', '1545-01-01T00:00:00Z')]
# [('countryname', 'Arakkal'), ('inception', '1545-01-01T00:00:00Z')]
# [('countryname', 'Tsardom of Russia'), ('inception', '1547-01-01T00:00:00Z')]
# [('countryname', 'Prince of Sedan'), ('inception', '1549-09-07T00:00:00Z')]
# [('countryname', 'Principality of Auersperg'), ('inception', '1550-01-01T00:00:00Z')]
# [('countryname', 'Kingdom of Loango'), ('inception', '1550-01-01T00:00:00Z')]
# [('countryname', 'Mahra Sultanate'), ('inception', '1550-01-01T00:00:00Z')]
# [('countryname', 'Military Frontier'), ('inception', '1553-01-01T00:00:00Z')]
# [('countryname', 'Sundem'), ('inception', '1555-01-01T00:00:00Z')]
# [('countryname', 'Baol'), ('inception', '1555-01-01T00:00:00Z')]
# [('countryname', 'Kingdom of Imereti'), ('inception', '1555-06-08T00:00:00Z')]
# [('countryname', 'Gorkha Kingdom'), ('inception', '1559-01-01T00:00:00Z')]
# [('countryname', 'Duchy of Courland and Semigallia'), ('inception', '1561-01-01T00:00:00Z')]
# [('countryname', 'Duchy of Estonia'), ('inception', '1561-01-01T00:00:00Z')]
# [('countryname', 'Pietraperzia principality'), ('inception', '1564-01-01T00:00:00Z')]
# [('countryname', 'Captaincy General of the Philippines'), ('inception', '1565-05-17T00:00:00Z')]
# [('countryname', 'Landgraviate of Hesse-Darmstadt'), ('inception', '1567-01-01T00:00:00Z')]
# [('countryname', 'Landgraviate of Hesse-Kassel'), ('inception', '1567-01-01T00:00:00Z')]
# [('countryname', 'Palatinate-Zweibrücken-Vohenstrauss-Parkstein'), ('inception', '1569-01-01T00:00:00Z')]
# [('countryname', 'Polish–Lithuanian Commonwealth'), ('inception', '1569-06-21T00:00:00Z')]
# [('countryname', 'Grand Duchy of Tuscany'), ('inception', '1569-09-06T00:00:00Z')]
# [('countryname', 'Principality of Bidache'), ('inception', '1570-01-01T00:00:00Z')]
# [('countryname', 'Principality of Transylvania'), ('inception', '1570-08-26T00:00:00Z')]
# [('countryname', 'Saxe-Weimar'), ('inception', '1572-01-01T00:00:00Z')]
# [('countryname', 'Duchy of Bielsko'), ('inception', '1572-01-01T00:00:00Z')]
# [('countryname', 'Duchy of Montferrat'), ('inception', '1574-01-01T00:00:00Z')]
# [('countryname', 'Hohenzollern-Hechingen'), ('inception', '1576-01-01T00:00:00Z')]
# [('countryname', 'Koch Hajo'), ('inception', '1581-01-01T00:00:00Z')]
# [('countryname', 'British Empire'), ('inception', '1583-01-01T00:00:00Z')]
# [('countryname', 'Saxe-Eisenach'), ('inception', '1596-01-01T00:00:00Z')]
# [('countryname', 'Saxe-Coburg'), ('inception', '1596-01-01T00:00:00Z')]
# [('countryname', 'Principality of Masserano'), ('inception', '1598-08-13T00:00:00Z')]
# [('countryname', 'Schwarzburg-Rudolstadt'), ('inception', '1599-01-01T00:00:00Z')]
# [('countryname', 'Schwarzburg-Sondershausen'), ('inception', '1599-01-01T00:00:00Z')]
# [('countryname', 'Kingdom of Niumi'), ('inception', '1600-01-01T00:00:00Z')]
# [('countryname', 'Baban'), ('inception', '1600-01-01T00:00:00Z')]
# [('countryname', 'Pflegamt Hauseck'), ('inception', '1600-01-01T00:00:00Z')]
# [('countryname', 'Duchy of Saxe-Altenburg'), ('inception', '1602-01-01T00:00:00Z')]
# [('countryname', 'Sultanate of Darfur'), ('inception', '1603-01-01T00:00:00Z')]
# [('countryname', 'Sayn-Wittgenstein-Berleburg'), ('inception', '1607-01-01T00:00:00Z')]
# [('countryname', 'Captaincy General of Cuba'), ('inception', '1607-01-01T00:00:00Z')]
# [('countryname', 'Swedish Empire'), ('inception', '1611-01-01T00:00:00Z')]
# [('countryname', 'Principato di Scaletta'), ('inception', '1614-07-22T00:00:00Z')]
# [('countryname', 'Brandenburg-Prussia'), ('inception', '1618-01-01T00:00:00Z')]
# [('countryname', 'Kasanje Kingdom'), ('inception', '1620-01-01T00:00:00Z')]
# [('countryname', 'Duchy of Guastalla'), ('inception', '1621-01-01T00:00:00Z')]
# [('countryname', 'Hesse-Homburg'), ('inception', '1622-01-01T00:00:00Z')]
# [('countryname', 'Prince of Leonforte'), ('inception', '1622-01-01T00:00:00Z')]
# [('countryname', 'Saint-Domingue'), ('inception', '1626-01-01T00:00:00Z')]
# [('countryname', 'Duchy of Friedland'), ('inception', '1627-01-01T00:00:00Z')]
# [('countryname', 'Principality of Monforte'), ('inception', '1628-01-01T00:00:00Z')]
# [('countryname', 'Kalmyk Khanate'), ('inception', '1630-01-01T00:00:00Z')]
# [('countryname', 'Asahan Sultanate'), ('inception', '1630-01-01T00:00:00Z')]
# [('countryname', 'Anhalt-Harzgerode'), ('inception', '1635-01-01T00:00:00Z')]
# [('countryname', 'Swedish overseas colonies'), ('inception', '1638-01-01T00:00:00Z')]
# [('countryname', 'Saxe-Gotha'), ('inception', '1640-01-01T00:00:00Z')]
# [('countryname', 'Kazikumukh Khanate'), ('inception', '1642-01-01T00:00:00Z')]
# [('countryname', 'Duchy of Bremen and Verden'), ('inception', '1648-01-01T00:00:00Z')]
# [('countryname', 'Principality of Minden'), ('inception', '1648-01-01T00:00:00Z')]
# [('countryname', 'Jersey'), ('inception', '1651-12-12T00:00:00Z')]
# [('countryname', 'Saxe-Merseburg'), ('inception', '1657-01-01T00:00:00Z')]
# [('countryname', 'Principality of Anhalt-Dornburg'), ('inception', '1667-01-01T00:00:00Z')]
# [('countryname', 'Ashanti kingdom'), ('inception', '1670-01-01T00:00:00Z')]
# [('countryname', 'British Leeward Islands'), ('inception', '1671-01-01T00:00:00Z')]
# [('countryname', 'Saxe-Jena'), ('inception', '1672-01-01T00:00:00Z')]
# [('countryname', 'Saxe-Meiningen'), ('inception', '1675-01-01T00:00:00Z')]
# [('countryname', 'House of Hornes'), ('inception', '1677-01-01T00:00:00Z')]
# [('countryname', 'Saxe-Römhild'), ('inception', '1680-01-01T00:00:00Z')]
# [('countryname', 'Saxe-Saalfeld'), ('inception', '1680-01-01T00:00:00Z')]
# [('countryname', 'Saxe-Eisenberg'), ('inception', '1680-01-01T00:00:00Z')]
# [('countryname', 'Dominion of New England'), ('inception', '1686-01-01T00:00:00Z')]
# [('countryname', 'Aro Confederacy'), ('inception', '1690-01-01T00:00:00Z')]
# [('countryname', 'Tarauli'), ('inception', '1690-01-01T00:00:00Z')]
# [('countryname', 'Principality of Thuận Thành'), ('inception', '1695-01-01T00:00:00Z')]
# [('countryname', 'Kingdom of Slavonia'), ('inception', '1699-01-01T00:00:00Z')]
# [('countryname', 'Monarchy of Spain'), ('inception', '1700-01-01T00:00:00Z')]
# [('countryname', 'Mutondo'), ('inception', '1700-01-01T00:00:00Z')]
# [('countryname', 'Kingdom of Wémè'), ('inception', '1700-01-01T00:00:00Z')]
# [('countryname', 'Kingdom of Prussia'), ('inception', '1701-01-18T00:00:00Z')]
# [('countryname', 'Principality of Orange-Nassau'), ('inception', '1702-01-01T00:00:00Z')]
# [('countryname', 'Beylik of Tunis'), ('inception', '1705-01-01T00:00:00Z')]
# [('countryname', 'Principality of Hà Tiên'), ('inception', '1707-01-01T00:00:00Z')]
# [('countryname', 'Kingdom of Vientiane'), ('inception', '1707-01-01T00:00:00Z')]
# [('countryname', 'Hohenlohe-Weikersheim'), ('inception', '1708-01-01T00:00:00Z')]
# [('countryname', 'Kingdom of Champasak'), ('inception', '1713-01-01T00:00:00Z')]
# [('countryname', 'Principality of Bengal'), ('inception', '1717-01-01T00:00:00Z')]
# [('countryname', 'Solms-Hohensolms-Lich'), ('inception', '1718-01-01T00:00:00Z')]
# [('countryname', 'Sultanate of Serdang'), ('inception', '1723-01-01T00:00:00Z')]
# [('countryname', 'Saudi Arabia'), ('inception', '1727-01-01T00:00:00Z')]
# [('countryname', 'Sultanate of Bulungan'), ('inception', '1731-01-01T00:00:00Z')]
# [('countryname', 'Sikh Empire'), ('inception', '1733-01-01T00:00:00Z')]
# [('countryname', 'Kingdom of Sicily (1734-1816)'), ('inception', '1734-01-01T00:00:00Z')]
# [('countryname', 'Baku Khanate'), ('inception', '1735-01-01T00:00:00Z')]
# [('countryname', 'Kingdom of Corsica'), ('inception', '1736-01-01T00:00:00Z')]
# [('countryname', 'Erivan Khanate'), ('inception', '1736-01-01T00:00:00Z')]
# [('countryname', 'Restored Hanthawaddy Kingdom'), ('inception', '1740-11-29T00:00:00Z')]
# [('countryname', 'Saxe-Weimar-Eisenach'), ('inception', '1741-01-01T00:00:00Z')]
# [('countryname', 'Austrian Silesia'), ('inception', '1742-01-01T00:00:00Z')]
# [('countryname', 'Shaki Khanate'), ('inception', '1743-01-01T00:00:00Z')]
# [('countryname', 'Shamshadil'), ('inception', '1747-01-01T00:00:00Z')]
# [('countryname', 'Nakhichevan Khanate'), ('inception', '1747-01-01T00:00:00Z')]
# [('countryname', 'Durrani Empire'), ('inception', '1747-01-01T00:00:00Z')]
# [('countryname', 'Javad khanate'), ('inception', '1747-01-01T00:00:00Z')]
# [('countryname', 'Derbent khanate'), ('inception', '1747-01-01T00:00:00Z')]
# [('countryname', 'Ganja khanate'), ('inception', '1747-01-01T00:00:00Z')]
# [('countryname', 'misl'), ('inception', '1748-01-01T00:00:00Z')]
# [('countryname', 'Karabakh Khanate'), ('inception', '1750-01-01T00:00:00Z')]
# [('countryname', 'Roman Catholic Diocese of Fulda'), ('inception', '1752-10-05T00:00:00Z')]
# [('countryname', 'Gorizia and Gradisca'), ('inception', '1754-01-01T00:00:00Z')]
# [('countryname', 'Yogyakarta Sultanate'), ('inception', '1755-01-01T00:00:00Z')]
# [('countryname', 'Mangkunegaran'), ('inception', '1757-01-01T00:00:00Z')]
# [('countryname', 'Kingdom of Kartli-Kakheti'), ('inception', '1762-01-01T00:00:00Z')]
# [('countryname', 'Thailand'), ('inception', '1768-12-28T00:00:00Z')]
# [('countryname', 'Kingdom of Galicia and Lodomeria'), ('inception', '1772-01-01T00:00:00Z')]
# [('countryname', 'Emirate of Umm Al Quwain'), ('inception', '1775-01-01T00:00:00Z')]
# [('countryname', 'Principality of Reuss-Greiz'), ('inception', '1778-01-01T00:00:00Z')]
# [('countryname', 'Rattanakosin Kingdom'), ('inception', '1782-01-01T00:00:00Z')]
# [('countryname', 'Tashkent State'), ('inception', '1784-01-01T00:00:00Z')]
# [('countryname', 'Kingdom of Tahiti'), ('inception', '1788-01-01T00:00:00Z')]
# [('countryname', 'New South Wales'), ('inception', '1788-01-01T00:00:00Z')]
# [('countryname', 'Principality of Lippe'), ('inception', '1789-01-01T00:00:00Z')]
# [('countryname', 'Emirate of Sharjah'), ('inception', '1793-12-02T00:00:00Z')]
# [('countryname', 'Anglo-Corsican Kingdom'), ('inception', '1794-01-01T00:00:00Z')]
# [('countryname', 'Mangbetu kingdom'), ('inception', '1800-01-01T00:00:00Z')]
# [('countryname', 'Kingdom of Etruria'), ('inception', '1801-03-21T00:00:00Z')]
# [('countryname', 'Principality of Salm'), ('inception', '1802-10-30T00:00:00Z')]
# [('countryname', 'Electorate of Salzburg'), ('inception', '1803-01-01T00:00:00Z')]
# [('countryname', 'Principalit of Lübeck'), ('inception', '1803-01-01T00:00:00Z')]
# [('countryname', 'Electorate of Württemberg'), ('inception', '1803-01-01T00:00:00Z')]
# [('countryname', 'Principality of Nassau-Orange-Fulda'), ('inception', '1803-01-01T00:00:00Z')]
# [('countryname', 'Principality of Krautheim'), ('inception', '1803-01-01T00:00:00Z')]
# [('countryname', 'Principality of Aschaffenburg'), ('inception', '1803-01-01T00:00:00Z')]
# [('countryname', 'Electorate of Hesse'), ('inception', '1803-01-01T00:00:00Z')]
# [('countryname', 'Principality Paderborn'), ('inception', '1803-01-01T00:00:00Z')]
# [('countryname', 'Principality Rheina-Wolbeck'), ('inception', '1803-02-14T00:00:00Z')]
# [('countryname', 'First Empire of Haiti'), ('inception', '1804-01-01T00:00:00Z')]
# [('countryname', 'Grand Duchy of Würzburg'), ('inception', '1805-01-01T00:00:00Z')]
# [('countryname', 'Kingdom of Italy'), ('inception', '1805-03-17T00:00:00Z')]
# [('countryname', 'Kingdom of Saxony'), ('inception', '1806-01-01T00:00:00Z')]
# [('countryname', 'Grand Duchy of Hesse'), ('inception', '1806-01-01T00:00:00Z')]
# [('countryname', 'Principality of Reuss-Gera'), ('inception', '1806-01-01T00:00:00Z')]
# [('countryname', 'Duchy of Nassau'), ('inception', '1806-01-01T00:00:00Z')]
# [('countryname', 'Kingdom of Bavaria'), ('inception', '1806-01-01T00:00:00Z')]
# [('countryname', 'Grand Duchy of Berg'), ('inception', '1806-01-01T00:00:00Z')]
# [('countryname', 'Principality of Ponte Corvo'), ('inception', '1806-01-01T00:00:00Z')]
# [('countryname', 'Principality of Leyen'), ('inception', '1806-01-01T00:00:00Z')]
# [('countryname', 'Kingdom of Naples'), ('inception', '1806-05-11T00:00:00Z')]
# [('countryname', 'Principality of Benevento'), ('inception', '1806-06-05T00:00:00Z')]
# [('countryname', 'Liechtenstein'), ('inception', '1806-07-12T00:00:00Z')]
# [('countryname', 'Kingdom of Westphalia'), ('inception', '1807-01-01T00:00:00Z')]
# [('countryname', 'Kingdom of Spain under Joseph Bonaparte'), ('inception', '1808-06-06T00:00:00Z')]
# [('countryname', 'Saxe-Weimar-Eisenach'), ('inception', '1809-01-01T00:00:00Z')]
# [('countryname', 'Kingdom of Setul Mambang Segara'), ('inception', '1810-01-01T00:00:00Z')]
# [('countryname', 'Islands of Refreshment'), ('inception', '1811-02-04T00:00:00Z')]
# [('countryname', 'Kura Khanate'), ('inception', '1812-01-01T00:00:00Z')]
# [('countryname', 'Grand Duchy of Oldenburg'), ('inception', '1814-01-01T00:00:00Z')]
# [('countryname', 'Kingdom of Norway (1814)'), ('inception', '1814-01-01T00:00:00Z')]
# [('countryname', 'Principality of Elba'), ('inception', '1814-04-14T00:00:00Z')]
# [('countryname', 'Norway'), ('inception', '1814-05-17T00:00:00Z')]
# [('countryname', 'Union between Sweden and Norway'), ('inception', '1814-11-04T00:00:00Z')]
# [('countryname', 'Grand Duchy of Mecklenburg-Strelitz'), ('inception', '1815-01-01T00:00:00Z')]
# [('countryname', 'Duchy of Lucca'), ('inception', '1815-01-01T00:00:00Z')]
# [('countryname', 'Luxembourg'), ('inception', '1815-01-01T00:00:00Z')]
# [('countryname', 'Kingdom of Brazil'), ('inception', '1815-01-01T00:00:00Z')]
# [('countryname', 'Kingdom of the Netherlands'), ('inception', '1815-03-16T00:00:00Z')]
# [('countryname', 'Kingdom of Lombardy–Venetia'), ('inception', '1815-04-07T00:00:00Z')]
# [('countryname', 'Kingdom of Dalmatia'), ('inception', '1815-06-22T00:00:00Z')]
# [('countryname', 'Principality of Lichtenberg'), ('inception', '1816-01-01T00:00:00Z')]
# [('countryname', 'Kingdom of Illyria'), ('inception', '1816-01-01T00:00:00Z')]
# [('countryname', 'Riau-Lingga Sultanate'), ('inception', '1819-01-01T00:00:00Z')]
# [('countryname', 'Gaza Empire'), ('inception', '1824-01-01T00:00:00Z')]
# [('countryname', 'duchy of Saxe-Coburg and Gotha'), ('inception', '1826-01-01T00:00:00Z')]
# [('countryname', 'Belgium'), ('inception', '1830-10-04T00:00:00Z')]
# [('countryname', 'Kingdom of Greece'), ('inception', '1832-01-01T00:00:00Z')]
# [('countryname', 'British Windward Islands'), ('inception', '1833-01-01T00:00:00Z')]
# [('countryname', 'Emirate of Jabal Shammar'), ('inception', '1836-01-01T00:00:00Z')]
# [('countryname', 'South Australia'), ('inception', '1836-12-28T00:00:00Z')]
# [('countryname', 'Regency of Araújo Lima'), ('inception', '1837-09-19T00:00:00Z')]
# [('countryname', 'Đại Nam'), ('inception', '1839-01-01T00:00:00Z')]
# [('countryname', 'Kingdom of Kubang Pasu Darul Qiyam'), ('inception', '1839-01-01T00:00:00Z')]
# [('countryname', 'Raj of Sarawak'), ('inception', '1841-09-24T00:00:00Z')]
# [('countryname', 'Kingdom of Sicily'), ('inception', '1848-03-25T00:00:00Z')]
# [('countryname', 'Duchy of Bukovina'), ('inception', '1849-01-01T00:00:00Z')]
# [('countryname', 'Duchy of Salzburg'), ('inception', '1849-01-01T00:00:00Z')]
# [('countryname', 'Principality of Montenegro'), ('inception', '1852-01-01T00:00:00Z')]
# [('countryname', 'Kingdom of Araucanía and Patagonia'), ('inception', '1860-11-17T00:00:00Z')]
# [('countryname', 'Duchy of Anhalt'), ('inception', '1863-01-01T00:00:00Z')]
# [('countryname', 'Second Mexican Empire'), ('inception', '1864-01-01T00:00:00Z')]
# [('countryname', 'Yettishar'), ('inception', '1865-01-01T00:00:00Z')]
# [('countryname', 'Kingdom of Redonda'), ('inception', '1865-01-01T00:00:00Z')]
# [('countryname', 'Khedivate of Egypt'), ('inception', '1867-06-08T00:00:00Z')]
# [('countryname', 'Canada'), ('inception', '1867-07-01T00:00:00Z')]
# [('countryname', 'Kingdom of Croatia-Slavonia'), ('inception', '1868-01-01T00:00:00Z')]
# [('countryname', 'Emirate of Ras Al Khaimah'), ('inception', '1869-01-01T00:00:00Z')]
# [('countryname', 'Qatar'), ('inception', '1870-01-01T00:00:00Z')]
# [('countryname', 'Austro-Hungarian rule in Bosnia and Herzegovina'), ('inception', '1878-01-01T00:00:00Z')]
# [('countryname', 'Bechuanaland Protectorate'), ('inception', '1885-01-01T00:00:00Z')]
# [('countryname', 'Kingdom of Sedang'), ('inception', '1888-01-01T00:00:00Z')]
# [('countryname', 'Principality of Trinidad'), ('inception', '1893-01-01T00:00:00Z')]
# [('countryname', 'Amashangana Tribal Authority'), ('inception', '1897-01-01T00:00:00Z')]
# [('countryname', 'Sultanate of Darfur'), ('inception', '1898-01-01T00:00:00Z')]
# [('countryname', 'Australia'), ('inception', '1901-01-01T00:00:00Z')]
# [('countryname', 'Modern Saudi State'), ('inception', '1902-01-01T00:00:00Z')]
# [('countryname', 'Saskatchewan'), ('inception', '1905-01-01T00:00:00Z')]
# [('countryname', 'Norway'), ('inception', '1905-06-07T00:00:00Z')]
# [('countryname', 'Norway'), ('inception', '1905-10-26T00:00:00Z')]
# [('countryname', 'New Zealand'), ('inception', '1907-09-26T00:00:00Z')]
# [('countryname', 'Kingdom of Bulgaria'), ('inception', '1908-01-01T00:00:00Z')]
# [('countryname', 'Bogd Khanate'), ('inception', '1911-12-01T00:00:00Z')]
# [('countryname', 'Tibet'), ('inception', '1912-01-01T00:00:00Z')]
# [('countryname', 'Kingdom of Poland'), ('inception', '1916-01-01T00:00:00Z')]
# [('countryname', 'Duchy of Courland and Semigallia'), ('inception', '1918-01-01T00:00:00Z')]
# [('countryname', 'United Baltic Duchy'), ('inception', '1918-01-01T00:00:00Z')]
# [('countryname', 'Roman Catholic Archdiocese of Riga'), ('inception', '1918-01-01T00:00:00Z')]
# [('countryname', 'Kingdom of Lithuania'), ('inception', '1918-02-16T00:00:00Z')]
# [('countryname', 'Kingdom of Lithuania'), ('inception', '1918-07-11T00:00:00Z')]
# [('countryname', 'Yugoslavia'), ('inception', '1918-12-01T00:00:00Z')]
# [('countryname', 'Kingdom of Iceland'), ('inception', '1918-12-01T00:00:00Z')]
# [('countryname', 'Territory of New Guinea'), ('inception', '1919-01-01T00:00:00Z')]
# [('countryname', 'Arab Kingdom of Syria'), ('inception', '1920-01-01T00:00:00Z')]
# [('countryname', 'Kingdom of Iraq'), ('inception', '1921-01-01T00:00:00Z')]
# [('countryname', 'Sultanate of Nejd'), ('inception', '1921-01-01T00:00:00Z')]
# [('countryname', 'Northern Ireland'), ('inception', '1921-05-08T00:00:00Z')]
# [('countryname', 'United Kingdom'), ('inception', '1927-04-12T00:00:00Z')]
# [('countryname', 'Vatican City'), ('inception', '1929-02-11T00:00:00Z')]
# [('countryname', 'Francoist Spain'), ('inception', '1939-04-01T00:00:00Z')]
# [('countryname', 'Principality of the Pindus'), ('inception', '1941-01-01T00:00:00Z')]
# [('countryname', 'Malayan Union'), ('inception', '1946-01-01T00:00:00Z')]
# [('countryname', 'Jordan'), ('inception', '1946-01-01T00:00:00Z')]
# [('countryname', 'Kingdom of Laos'), ('inception', '1947-01-01T00:00:00Z')]
# [('countryname', 'Government of Japan'), ('inception', '1947-01-01T00:00:00Z')]
# [('countryname', 'Japan'), ('inception', '1947-05-03T00:00:00Z')]
# [('countryname', 'Malaya'), ('inception', '1948-01-01T00:00:00Z')]
# [('countryname', 'Emirate of Cyrenaica'), ('inception', '1949-01-01T00:00:00Z')]
# [('countryname', 'Bhutan'), ('inception', '1949-08-08T00:00:00Z')]
# [('countryname', 'Federation of Rhodesia and Nyasaland'), ('inception', '1953-01-01T00:00:00Z')]
# [('countryname', 'Emirate of Fujairah'), ('inception', '1953-01-01T00:00:00Z')]
# [('countryname', 'Cambodia'), ('inception', '1953-11-09T00:00:00Z')]
# [('countryname', 'Kingdom of Cambodia'), ('inception', '1953-11-09T00:00:00Z')]
# [('countryname', 'Netherlands'), ('inception', '1954-12-15T00:00:00Z')]
# [('countryname', 'Netherlands Antilles'), ('inception', '1954-12-15T00:00:00Z')]
# [('countryname', 'Malaysia'), ('inception', '1957-01-01T00:00:00Z')]
# [('countryname', 'Saint Christopher-Nevis-Anguilla'), ('inception', '1958-01-01T00:00:00Z')]
# [('countryname', 'West Indies Federation'), ('inception', '1958-01-01T00:00:00Z')]
# [('countryname', 'South Kasai'), ('inception', '1960-01-01T00:00:00Z')]
# [('countryname', 'Jamaica'), ('inception', '1962-01-01T00:00:00Z')]
# [('countryname', 'Lesotho'), ('inception', '1966-01-01T00:00:00Z')]
# [('countryname', 'Barbados'), ('inception', '1966-11-30T00:00:00Z')]
# [('countryname', 'Saint Kitts and Nevis'), ('inception', '1967-02-27T00:00:00Z')]
# [('countryname', 'Saint Lucia'), ('inception', '1967-03-01T00:00:00Z')]
# [('countryname', 'Principality of Sealand'), ('inception', '1967-09-02T00:00:00Z')]
# [('countryname', 'Eswatini'), ('inception', '1968-09-06T00:00:00Z')]
# [('countryname', 'Oman'), ('inception', '1970-07-23T00:00:00Z')]
# [('countryname', 'United Arab Emirates'), ('inception', '1971-01-01T00:00:00Z')]
# [('countryname', 'Bahrain'), ('inception', '1971-08-14T00:00:00Z')]
# [('countryname', 'Emirate of Ajman'), ('inception', '1971-12-02T00:00:00Z')]
# [('countryname', 'The Bahamas'), ('inception', '1973-01-01T00:00:00Z')]
# [('countryname', 'monarchy of the Bahamas'), ('inception', '1973-07-10T00:00:00Z')]
# [('countryname', 'Grenada'), ('inception', '1974-01-01T00:00:00Z')]
# [('countryname', 'Papua New Guinea'), ('inception', '1975-01-01T00:00:00Z')]
# [('countryname', 'Central African Empire'), ('inception', '1976-12-04T00:00:00Z')]
# [('countryname', 'Tuvalu'), ('inception', '1978-01-01T00:00:00Z')]
# [('countryname', 'Solomon Islands'), ('inception', '1978-01-01T00:00:00Z')]
# [('countryname', 'Monarchy of the Solomon Islands'), ('inception', '1978-07-07T00:00:00Z')]
# [('countryname', 'Greenland'), ('inception', '1979-01-01T00:00:00Z')]
# [('countryname', 'Saint Vincent and the Grenadines'), ('inception', '1979-01-01T00:00:00Z')]
# [('countryname', 'Saint Lucia'), ('inception', '1979-02-22T00:00:00Z')]
# [('countryname', 'Talossa'), ('inception', '1979-12-26T00:00:00Z')]
# [('countryname', 'Grand Duchy of Avram'), ('inception', '1980-01-01T00:00:00Z')]
# [('countryname', 'Belize'), ('inception', '1981-09-21T00:00:00Z')]
# [('countryname', 'monarchy of Antigua and Barbuda'), ('inception', '1981-11-01T00:00:00Z')]
# [('countryname', 'Antigua and Barbuda'), ('inception', '1981-11-01T00:00:00Z')]
# [('countryname', 'Brunei'), ('inception', '1984-01-01T00:00:00Z')]
# [('countryname', 'New Zealand'), ('inception', '1986-12-13T00:00:00Z')]
# [('countryname', 'Aerican Empire'), ('inception', '1987-05-08T00:00:00Z')]
# [('countryname', 'Kuwait'), ('inception', '1991-02-26T00:00:00Z')]
# [('countryname', 'Ladonia'), ('inception', '1996-06-02T00:00:00Z')]
# [('countryname', 'Duchess of Palma de Mallorca'), ('inception', '1997-01-01T00:00:00Z')]
# [('countryname', 'Holy Empire of Reunion'), ('inception', '1997-01-01T00:00:00Z')]
# [('countryname', 'Islamic State of Iraq and the Levant'), ('inception', '1999-01-01T00:00:00Z')]
# [('countryname', 'Gay and Lesbian Kingdom of the Coral Sea Islands'), ('inception', '2004-06-14T00:00:00Z')]
# [('countryname', 'Principality of Wy'), ('inception', '2004-11-15T00:00:00Z')]
# [('countryname', 'Islamic State of Iraq and the Levant'), ('inception', '2006-01-01T00:00:00Z')]
# [('countryname', 'Grand Duchy of Flandrensis'), ('inception', '2008-01-01T00:00:00Z')]
# [('countryname', 'Grand Duchy of Flandrensis'), ('inception', '2008-09-04T00:00:00Z')]
# [('countryname', 'Romanov Empire'), ('inception', '2011-07-20T00:00:00Z')]
# [('countryname', 'Asgardia'), ('inception', '2016-10-12T00:00:00Z')]
# [('countryname', 'Kingdom of Africa'), ('inception', '2020-05-25T00:00:00Z')]
# [('countryname', 'Phoenicia'), ('inception', '-2499-01-01T00:00:00Z')]
# [('countryname', 'Akkadian empire'), ('inception', '-2333-01-01T00:00:00Z')]
# [('countryname', 'Yamhad'), ('inception', '-2003-01-01T00:00:00Z')]
# [('countryname', 'Alashiya'), ('inception', '-2000-01-01T00:00:00Z')]
# [('countryname', 'First Babylonian Empire'), ('inception', '-1829-01-01T00:00:00Z')]
# [('countryname', 'Colchis'), ('inception', '-1700-01-01T00:00:00Z')]
# [('countryname', 'Mitanni'), ('inception', '-1649-01-01T00:00:00Z')]
# [('countryname', 'Hittite Empire'), ('inception', '-1600-01-01T00:00:00Z')]
# [('countryname', 'Hayasa-Azzi'), ('inception', '-1501-01-01T00:00:00Z')]
# [('countryname', 'Kuru Kingdom'), ('inception', '-1200-01-01T00:00:00Z')]
# [('countryname', 'Gurgum'), ('inception', '-1200-01-01T00:00:00Z')]
# [('countryname', 'Anga Kingdom'), ('inception', '-1100-01-01T00:00:00Z')]
# [('countryname', 'Qi'), ('inception', '-1044-01-01T00:00:00Z')]
# [('countryname', 'Dʿmt'), ('inception', '-979-01-01T00:00:00Z')]
# [('countryname', 'Kingdom of Israel'), ('inception', '-929-01-01T00:00:00Z')]
# [('countryname', 'Judah'), ('inception', '-929-01-01T00:00:00Z')]
# [('countryname', 'Pauravas'), ('inception', '-889-01-01T00:00:00Z')]
# [('countryname', 'Videha'), ('inception', '-850-01-01T00:00:00Z')]
# [('countryname', 'Ancient Carthage'), ('inception', '-813-01-01T00:00:00Z')]
# [('countryname', 'Avanti'), ('inception', '-700-01-01T00:00:00Z')]
# [('countryname', 'Surasena'), ('inception', '-700-01-01T00:00:00Z')]
# [('countryname', 'Kashi'), ('inception', '-699-01-01T00:00:00Z')]
# [('countryname', 'Media'), ('inception', '-677-01-01T00:00:00Z')]
# [('countryname', 'Kingdom of Armenia'), ('inception', '-552-01-01T00:00:00Z')]
# [('countryname', 'Achaemenid Empire'), ('inception', '-549-01-01T00:00:00Z')]
# [('countryname', 'Odrysian kingdom'), ('inception', '-459-01-01T00:00:00Z')]
# [('countryname', 'Bosporan Kingdom'), ('inception', '-436-01-01T00:00:00Z')]
# [('countryname', 'Kingdom of Aksum'), ('inception', '-400-01-01T00:00:00Z')]
# [('countryname', 'Morocco'), ('inception', '-399-01-01T00:00:00Z')]
# [('countryname', 'Minyue'), ('inception', '-333-01-01T00:00:00Z')]
# [('countryname', 'Kingdom of Cappadocia'), ('inception', '-320-01-01T00:00:00Z')]
# [('countryname', 'Seleucid Empire'), ('inception', '-311-01-01T00:00:00Z')]
# [('countryname', 'Thaton Kingdom'), ('inception', '-299-01-01T00:00:00Z')]
# [('countryname', 'Kingdom of Pontus'), ('inception', '-280-01-01T00:00:00Z')]
# [('countryname', 'Âu Lạc'), ('inception', '-256-01-01T00:00:00Z')]
# [('countryname', 'Parthian Empire'), ('inception', '-246-01-01T00:00:00Z')]
# [('countryname', 'Han dynasty'), ('inception', '-205-01-01T00:00:00Z')]
# [('countryname', 'Kingdom of Sophene'), ('inception', '-201-01-01T00:00:00Z')]
# [('countryname', 'Numidia'), ('inception', '-201-01-01T00:00:00Z')]
# [('countryname', 'Kingdom of Commagene'), ('inception', '-162-01-01T00:00:00Z')]
# [('countryname', 'Osroene'), ('inception', '-131-01-01T00:00:00Z')]
# [('countryname', 'Himyarite Kingdom'), ('inception', '-109-01-01T00:00:00Z')]
# [('countryname', 'Kingdom of Chalcis'), ('inception', '-080-01-01T00:00:00Z')]
# [('countryname', 'Dacia'), ('inception', '-059-01-01T00:00:00Z')]
# [('countryname', 'Apraca'), ('inception', '-014-01-01T00:00:00Z')]
# 802

# %% [markdown]
# # General instructions
#
# The goal of the project is to materialize a set of **exploratory workloads** over a real-world, large-scale,  open-domain KG: [WikiData](https://www.wikidata.org/wiki/Wikidata:Main_Page)
#
# An exploratory workload  is composed by a set of queries, where each query is related to the information obtained previously.
#
# An exploratory workload starts with a usually vague, open ended question, and does not assume the person issuing the workload has a clear understanding of the data contained in the target database or its structure.
#
# Remeber that:
#
# 1. All the queries must run in the python notebook
# 2. You can use classes and properties only if you find them via a SPARQL query that must be present in the notebook
# 3. You do not delete useless queries. Keep everything that is synthatically valid
#
# ```
# ?p <http://schema.org/name> ?name .
# ```
#
# is the BGP returning a human-readable name of a property or a class in Wikidata.

# %%
## SETUP used later

from SPARQLWrapper import SPARQLWrapper, JSON


prefixString = """
##-e1cf476009-##
PREFIX wd: <http://www.wikidata.org/entity/> 
PREFIX wdt: <http://www.wikidata.org/prop/direct/> 
PREFIX sc: <http://schema.org/>
"""

# select and construct queries
def run_query(queryString):
    to_run = prefixString + "\n" + queryString

    sparql = SPARQLWrapper("http://a256-gc1-02.srv.aau.dk:5820/sparql")
    sparql.setTimeout(300)
    sparql.setReturnFormat(JSON)
    sparql.setQuery(to_run)

    try :
       results = sparql.query()
       json_results = results.convert()
       if len(json_results['results']['bindings'])==0:
          print("Empty")
          return 0
    
       for bindings in json_results['results']['bindings']:
          print( [ (var, value['value'])  for var, value in bindings.items() ] )

       return len(json_results['results']['bindings'])

    except Exception as e :
        print("The operation failed", e)
    
# ASk queries
def run_ask_query(queryString):
    to_run = prefixString + "\n" + queryString

    sparql = SPARQLWrapper("http://a256-gc1-02.srv.aau.dk:5820/sparql")
    sparql.setTimeout(300)
    sparql.setReturnFormat(JSON)
    sparql.setQuery(to_run)

    try :
        return sparql.query().convert()

    except Exception as e :
        print("The operation failed", e)

# %% [markdown]
# # Politics Workflow Series ("Politicians in E.U.")
#
# Consider the following exploratory information need:
#
# > You investigating the careers of politicians in the E.U.

# %% [markdown]
# ## Useful URIs for the current workflow
#
#
# The following are given:
#
# | IRI           | Description   | Role      |
# | -----------   | -----------   |-----------|
# | `wdt:P1647`   | subproperty   | predicate |
# | `wdt:P31`     | instance of   | predicate |
# | `wdt:P279`    | subclass      | predicate |
# | `wdt:P17`     | country       | predicate |
# | `wdt:P27`     | citizenship   | predicate |
# | `wdt:P39`     | position held   | predicate |
# | `wdt:P106`    | profession   | predicate |
# | `wd:Q82955`   | politician | node      |
# | `wd:Q46`      | Europe        | node |
# | `wd:Q38`      | Italy          | node |
#
#
#
# Also consider
#
# ```
# ?p wdt:P106/wdt:P279* wd:Q82955  .
# ```
#
# is the BGP to retrieve all **politicians**

# %% [markdown]
# ## Workload Goals
#
#
# 1. Identify the BGP to retrieve E.U. countries and their politicians
#
# 2. Identify the BGP for obtaining other occupations and properties of politicians
#
# 3. How many politicians are recorder for each E.U. country?
#
# 4. Are there politicians with double citizenship?
#
# 5. Analyze the number of politicians in each country by occupation, for instance
#
#    5.1 What are the top-3 occupations for a politician in Italy and France?
#
#    5.2 What if you consider only politicians for which we don't have a date of death?
#
#    5.3 Which politicians had a spouse that was also a politician? How many in each country?

# %%
# start your workflow here

# %%
queryString = """
SELECT COUNT(*)
WHERE { 

# ?p wdt:P106/wdt:P279 wd:Q82955  . 
} 
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('callret-0', '15556')]
# 1

# %% [markdown]
# ## Task 1
# 1. Identify the BGP to retrieve E.U. countries and their politicians

# %%
# Let's see what happens if we use only the property "profession" (wdt:P106) to identify a politian
queryString = """
SELECT ?polname ?oname
WHERE { 

# ?pol wdt:P106 ?obj .

FILTER(?obj = wd:Q82955).

# ?pol <http://schema.org/name> ?polname .
# ?obj <http://schema.org/name> ?oname .
}
ORDER BY ASC (?polname)
LIMIT 10
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('polname', '"Big" Donnie MacLeod'), ('oname', 'politician')]
# [('polname', "'Abd Allah II ibn 'Ali 'Abd ash-Shakur"), ('oname', 'politician')]
# [('polname', "'Abd al-'Aziz ibn Marwan"), ('oname', 'politician')]
# [('polname', "'Abd al-Ilah"), ('oname', 'politician')]
# [('polname', "'Abd al-Razzaq al-Hasani"), ('oname', 'politician')]
# [('polname', "'Abdallah ibn Ishaq ibn Ibrahim"), ('oname', 'politician')]
# [('polname', "'Alisi Afeaki Taumoepeau"), ('oname', 'politician')]
# [('polname', "'Amr ibn Luhayy"), ('oname', 'politician')]
# [('polname', "'Aziz 'Ali al-Misri"), ('oname', 'politician')]
# [('polname', "'General' Elijah Combs"), ('oname', 'politician')]
# 10

# %%
# Let's see what is counted in the example query
queryString = """
SELECT ?polname ?oname
WHERE { 

# ?pol wdt:P106/wdt:P279 ?obj .

FILTER(?obj = wd:Q82955).

# ?pol <http://schema.org/name> ?polname .
# ?obj <http://schema.org/name> ?oname .
}
ORDER BY ASC (?polname)
LIMIT 10
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('polname', "'Amr ibn al-'As"), ('oname', 'politician')]
# [('polname', "'Apepi"), ('oname', 'politician')]
# [('polname', '...ka I'), ('oname', 'politician')]
# [('polname', '...ka II'), ('oname', 'politician')]
# [('polname', '...ka Nebnanati'), ('oname', 'politician')]
# [('polname', '...ren Hepu'), ('oname', 'politician')]
# [('polname', '...sa...'), ('oname', 'politician')]
# [('polname', '...webenra'), ('oname', 'politician')]
# [('polname', 'A Foster'), ('oname', 'politician')]
# [('polname', 'A G Phillips'), ('oname', 'politician')]
# 10

# %% [markdown]
# #### Comment
# The BGP to retrieve politians is different from the one usede in the example of query so I try to see what are the differences in using one or another
#
# QUERY -> ?p wdt:P106/wdt:P279 wd:Q82955  .
# BGP -> ?p wdt:P106/wdt:P279* wd:Q82955  .
#
# There is an asterisk more in the BGP expression

# %%
# Let's see if using the given BGP the results are different 
queryString = """
SELECT ?polname ?oname
WHERE { 

# ?pol wdt:P106/wdt:P279* ?obj .

FILTER(?obj = wd:Q82955).

# ?pol <http://schema.org/name> ?polname .
# ?obj <http://schema.org/name> ?oname .
}
ORDER BY ASC (?polname)
LIMIT 10
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('polname', '"Big" Donnie MacLeod'), ('oname', 'politician')]
# [('polname', "'Abd Allah II ibn 'Ali 'Abd ash-Shakur"), ('oname', 'politician')]
# [('polname', "'Abd Allāh ibn Muhammad ibn Ġānīya"), ('oname', 'politician')]
# [('polname', "'Abd al-'Aziz ibn Marwan"), ('oname', 'politician')]
# [('polname', "'Abd al-Ilah"), ('oname', 'politician')]
# [('polname', "'Abd al-Razzaq al-Hasani"), ('oname', 'politician')]
# [('polname', "'Abdallah ibn Ishaq ibn Ibrahim"), ('oname', 'politician')]
# [('polname', "'Abdawayh ibn Jabalah"), ('oname', 'politician')]
# [('polname', "'Abdun ibn Muhammad"), ('oname', 'politician')]
# [('polname', "'Adud al-Dawla"), ('oname', 'politician')]
# 10

# %% [markdown]
# #### Comment
# During a brief internet search I have discovered that "Big" Donnie MacLeod is actually a politician and so probably this last query is the one to be used.
#
# So let's look for which relation passes between a politician and the country which he/she works for and even the belonging of a country to the E.U.

# %%
#Let's check the belonging of a country to the E.U. tring with Italy
queryString = """
SELECT ?pname ?oname ?p ?obj
WHERE { 

wd:Q38 ?p ?obj .

# ?p <http://schema.org/name> ?pname .
OPTIONAL { ?obj <http://schema.org/name> ?oname .} .
}
ORDER BY ASC (?pname)
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('pname', 'AGROVOC ID'), ('p', 'http://www.wikidata.org/prop/direct/P8061'), ('obj', 'c_4026')]
# [('pname', 'ASC Leiden Thesaurus ID'), ('p', 'http://www.wikidata.org/prop/direct/P5198'), ('obj', '294918175')]
# [('pname', 'Academy Awards Database nominee ID'), ('p', 'http://www.wikidata.org/prop/direct/P6150'), ('obj', '7512')]
# [('pname', 'All the Tropes identifier'), ('p', 'http://www.wikidata.org/prop/direct/P8895'), ('obj', 'Italy')]
# [('pname', 'Analysis & Policy Observatory term ID'), ('p', 'http://www.wikidata.org/prop/direct/P7870'), ('obj', '10099')]
# [('pname', 'AniDB tag ID'), ('p', 'http://www.wikidata.org/prop/direct/P8785'), ('obj', '486')]
# [('pname', 'Armeniapedia ID'), ('p', 'http://www.wikidata.org/prop/direct/P9629'), ('obj', '2924')]
# [('pname', 'BBC News topic ID'), ('p', 'http://www.wikidata.org/prop/direct/P6200'), ('obj', 'crr7mlg0d2wt')]
# [('pname', 'BBC Things ID'), ('p', 'http://www.wikidata.org/prop/direct/P1617'), ('obj', '0021de37-b64a-46ac-a4bb-5bdbdf0908ec')]
# [('pname', 'BHCL UUID'), ('p', 'http://www.wikidata.org/prop/direct/P9037'), ('obj', '37872850-d9da-4cc4-b1dd-0f54053e8a1e')]
# [('pname', 'BHCL UUID'), ('p', 'http://www.wikidata.org/prop/direct/P9037'), ('obj', 'eced42c8-d06d-4ea3-b038-50674f687336')]
# [('pname', 'BabelNet ID'), ('p', 'http://www.wikidata.org/prop/direct/P2581'), ('obj', '00047705n')]
# [('pname', 'Basque Vikidia ID'), ('p', 'http://www.wikidata.org/prop/direct/P7832'), ('obj', 'Italia')]
# [('pname', 'Brockhaus Enzyklopädie online ID'), ('p', 'http://www.wikidata.org/prop/direct/P5019'), ('obj', 'italien')]
# [('pname', 'CIVICUS Monitor country entry'), ('p', 'http://www.wikidata.org/prop/direct/P5180'), ('obj', 'italy')]
# [('pname', 'CNA topic ID'), ('p', 'http://www.wikidata.org/prop/direct/P9368'), ('obj', 'italy')]
# [('pname', 'Catalan Vikidia ID'), ('p', 'http://www.wikidata.org/prop/direct/P9123'), ('obj', 'Itàlia')]
# [('pname', 'Comic Vine ID'), ('p', 'http://www.wikidata.org/prop/direct/P5905'), ('obj', '4020-55920')]
# [('pname', 'Commons category'), ('p', 'http://www.wikidata.org/prop/direct/P373'), ('obj', 'Italy')]
# [('pname', 'Commons gallery'), ('p', 'http://www.wikidata.org/prop/direct/P935'), ('obj', 'Italia')]
# [('pname', 'Curlie ID'), ('p', 'http://www.wikidata.org/prop/direct/P998'), ('obj', 'Regional/Europe/Italy/')]
# [('pname', 'DR topic ID'), ('p', 'http://www.wikidata.org/prop/direct/P6849'), ('obj', 'italien')]
# [('pname', 'Dagens Nyheter topic ID'), ('p', 'http://www.wikidata.org/prop/direct/P3509'), ('obj', 'italien')]
# [('pname', 'Dewey Decimal Classification'), ('p', 'http://www.wikidata.org/prop/direct/P1036'), ('obj', '2--45')]
# [('pname', 'Dreadnought Project page'), ('p', 'http://www.wikidata.org/prop/direct/P4589'), ('obj', 'Italy')]
# [('pname', 'EMLO location ID'), ('p', 'http://www.wikidata.org/prop/direct/P4672'), ('obj', '6851bdbb-c4fa-4b58-8096-dd5153da907b')]
# [('pname', 'EMLO location ID'), ('p', 'http://www.wikidata.org/prop/direct/P4672'), ('obj', '68e102af-524a-4f20-8632-b5553c56dd5b')]
# [('pname', 'Encyclopedia of China Online Database ID'), ('p', 'http://www.wikidata.org/prop/direct/P9545'), ('obj', '242833')]
# [('pname', 'Encyclopedia of Modern Ukraine ID'), ('p', 'http://www.wikidata.org/prop/direct/P4613'), ('obj', '12857')]
# [('pname', 'Encyclopedia of the History of Ukraine ID'), ('p', 'http://www.wikidata.org/prop/direct/P8935'), ('obj', 'Italija')]
# [('pname', 'Encyclopedie berbere keyword ID'), ('p', 'http://www.wikidata.org/prop/direct/P8472'), ('obj', '2549')]
# [('pname', 'Encyclopædia Britannica Online ID'), ('p', 'http://www.wikidata.org/prop/direct/P1417'), ('obj', 'place/Italy')]
# [('pname', 'Encyclopædia Universalis ID'), ('p', 'http://www.wikidata.org/prop/direct/P3219'), ('obj', 'italie-vue-d-ensemble')]
# [('pname', 'English Vikidia ID'), ('p', 'http://www.wikidata.org/prop/direct/P7829'), ('obj', 'Italy')]
# [('pname', 'EuroVoc ID'), ('p', 'http://www.wikidata.org/prop/direct/P5437'), ('obj', '1519')]
# [('pname', 'FAST ID'), ('p', 'http://www.wikidata.org/prop/direct/P2163'), ('obj', '1204565')]
# [('pname', 'FIPS 10-4 (countries and regions)'), ('p', 'http://www.wikidata.org/prop/direct/P901'), ('obj', 'IT')]
# [('pname', 'Fandom article ID'), ('p', 'http://www.wikidata.org/prop/direct/P6262'), ('obj', 'countries:Italy')]
# [('pname', 'Fandom article ID'), ('p', 'http://www.wikidata.org/prop/direct/P6262'), ('obj', 'cryptids12-everything:Italy')]
# [('pname', 'Fandom article ID'), ('p', 'http://www.wikidata.org/prop/direct/P6262'), ('obj', 'italy:Italy')]
# [('pname', 'Fandom wiki ID'), ('p', 'http://www.wikidata.org/prop/direct/P4073'), ('obj', 'italy')]
# [('pname', 'Freebase ID'), ('p', 'http://www.wikidata.org/prop/direct/P646'), ('obj', '/m/03rjj')]
# [('pname', 'French Vikidia ID'), ('p', 'http://www.wikidata.org/prop/direct/P7818'), ('obj', 'Italie')]
# [('pname', 'GACS ID'), ('p', 'http://www.wikidata.org/prop/direct/P4427'), ('obj', '547')]
# [('pname', 'GND ID'), ('p', 'http://www.wikidata.org/prop/direct/P227'), ('obj', '4027833-5')]
# [('pname', 'GS1 country code'), ('p', 'http://www.wikidata.org/prop/direct/P3067'), ('obj', '800-839')]
# [('pname', 'GeoNLP ID'), ('p', 'http://www.wikidata.org/prop/direct/P5400'), ('obj', '1xYMqN')]
# [('pname', 'GeoNames ID'), ('p', 'http://www.wikidata.org/prop/direct/P1566'), ('obj', '3175395')]
# [('pname', 'Getty Thesaurus of Geographic Names ID'), ('p', 'http://www.wikidata.org/prop/direct/P1667'), ('obj', '1000080')]
# [('pname', 'Giant Bomb ID'), ('p', 'http://www.wikidata.org/prop/direct/P5247'), ('obj', '3035-1451')]
# [('pname', 'GitHub topic'), ('p', 'http://www.wikidata.org/prop/direct/P9100'), ('obj', 'italy')]
# [('pname', 'Global Anabaptist Mennonite Encyclopedia Online ID'), ('p', 'http://www.wikidata.org/prop/direct/P1842'), ('obj', 'Italy')]
# [('pname', 'Gran Enciclopèdia Catalana ID'), ('p', 'http://www.wikidata.org/prop/direct/P1296'), ('obj', '0034099')]
# [('pname', 'Great Russian Encyclopedia Online ID'), ('p', 'http://www.wikidata.org/prop/direct/P2924'), ('obj', '2026445')]
# [('pname', 'Gregorian calendar start date'), ('p', 'http://www.wikidata.org/prop/direct/P7295'), ('obj', '1582-10-15T00:00:00Z')]
# [('pname', 'Grove Art Online ID'), ('p', 'http://www.wikidata.org/prop/direct/P8406'), ('obj', 'T042658')]
# [('pname', 'Guardian topic ID'), ('p', 'http://www.wikidata.org/prop/direct/P3106'), ('obj', 'world/italy')]
# [('pname', 'Gynopedia ID'), ('p', 'http://www.wikidata.org/prop/direct/P5843'), ('obj', 'Italy')]
# [('pname', 'HDS ID'), ('p', 'http://www.wikidata.org/prop/direct/P902'), ('obj', '011196')]
# [('pname', 'Hrvatska enciklopedija ID'), ('p', 'http://www.wikidata.org/prop/direct/P7982'), ('obj', '28030')]
# [('pname', 'Human Development Index'), ('p', 'http://www.wikidata.org/prop/direct/P1081'), ('obj', '0.873')]
# [('pname', 'IAB code'), ('p', 'http://www.wikidata.org/prop/direct/P5250'), ('obj', '1326')]
# [('pname', 'INSEE countries and foreign territories code'), ('p', 'http://www.wikidata.org/prop/direct/P3422'), ('obj', '99127')]
# [('pname', 'IOC country code'), ('p', 'http://www.wikidata.org/prop/direct/P984'), ('obj', 'ITA')]
# [('pname', 'IPA transcription'), ('p', 'http://www.wikidata.org/prop/direct/P898'), ('obj', 'iˈtalja')]
# [('pname', 'IPA transcription'), ('p', 'http://www.wikidata.org/prop/direct/P898'), ('obj', 'ɪˈtalʲɪjə')]
# [('pname', 'IPA transcription'), ('p', 'http://www.wikidata.org/prop/direct/P898'), ('obj', 'ɪˈtɑːlɪɑ')]
# [('pname', 'ISBN identifier group'), ('p', 'http://www.wikidata.org/prop/direct/P3097'), ('obj', '978-88')]
# [('pname', 'ISBN identifier group'), ('p', 'http://www.wikidata.org/prop/direct/P3097'), ('obj', '979-12')]
# [('pname', 'ISNI'), ('p', 'http://www.wikidata.org/prop/direct/P213'), ('obj', '0000 0001 2186 9395')]
# [('pname', 'ISO 3166-1 alpha-2 code'), ('p', 'http://www.wikidata.org/prop/direct/P297'), ('obj', 'IT')]
# [('pname', 'ISO 3166-1 alpha-3 code'), ('p', 'http://www.wikidata.org/prop/direct/P298'), ('obj', 'ITA')]
# [('pname', 'ISO 3166-1 numeric code'), ('p', 'http://www.wikidata.org/prop/direct/P299'), ('obj', '380')]
# [('pname', 'ITU letter code'), ('p', 'http://www.wikidata.org/prop/direct/P3024'), ('obj', 'I')]
# [('pname', 'ITU/ISO/IEC object identifier'), ('p', 'http://www.wikidata.org/prop/direct/P3743'), ('obj', '2.16.380')]
# [('pname', 'Interlingual Index ID'), ('p', 'http://www.wikidata.org/prop/direct/P5063'), ('obj', 'i83107')]
# [('pname', 'Invasive Species Compendium Datasheet ID'), ('p', 'http://www.wikidata.org/prop/direct/P5698'), ('obj', '108464')]
# [('pname', 'Italian Vikidia ID'), ('p', 'http://www.wikidata.org/prop/direct/P7822'), ('obj', 'Italia')]
# [('pname', 'JORFSearch organization ID'), ('p', 'http://www.wikidata.org/prop/direct/P6413'), ('obj', 'Q38')]
# [('pname', 'Jewish Encyclopedia ID (Russian)'), ('p', 'http://www.wikidata.org/prop/direct/P1438'), ('obj', '11873')]
# [('pname', 'Joconde discovery ID'), ('p', 'http://www.wikidata.org/prop/direct/P7960'), ('obj', 'T115-3841')]
# [('pname', 'Joconde location ID'), ('p', 'http://www.wikidata.org/prop/direct/P7850'), ('obj', 'T84-3294')]
# [('pname', 'KBpedia ID'), ('p', 'http://www.wikidata.org/prop/direct/P8408'), ('obj', 'Italy')]
# [('pname', 'Klexikon article ID'), ('p', 'http://www.wikidata.org/prop/direct/P6573'), ('obj', 'Italien')]
# [('pname', 'Le Monde diplomatique subject ID'), ('p', 'http://www.wikidata.org/prop/direct/P3612'), ('obj', 'pays/italie')]
# [('pname', 'Liber Liber author ID'), ('p', 'http://www.wikidata.org/prop/direct/P7208'), ('obj', 'i/italia')]
# [('pname', 'Library of Congress authority ID'), ('p', 'http://www.wikidata.org/prop/direct/P244'), ('obj', 'n79021783')]
# [('pname', 'LoC and MARC vocabularies ID'), ('p', 'http://www.wikidata.org/prop/direct/P4801'), ('obj', 'countries/it')]
# [('pname', 'Marine Regions Geographic IDentifier (MRGID)'), ('p', 'http://www.wikidata.org/prop/direct/P7322'), ('obj', '2133')]
# [('pname', 'MeSH descriptor ID'), ('p', 'http://www.wikidata.org/prop/direct/P486'), ('obj', 'D007558')]
# [('pname', 'MusicBrainz area ID'), ('p', 'http://www.wikidata.org/prop/direct/P982'), ('obj', 'c6500277-9a3d-349b-bf30-41afdbf42add')]
# [('pname', 'NALT ID'), ('p', 'http://www.wikidata.org/prop/direct/P2004'), ('obj', '1813')]
# [('pname', 'NE.se ID'), ('p', 'http://www.wikidata.org/prop/direct/P3222'), ('obj', 'italia')]
# [('pname', 'NE.se ID'), ('p', 'http://www.wikidata.org/prop/direct/P3222'), ('obj', 'italien')]
# [('pname', 'NKCR AUT ID'), ('p', 'http://www.wikidata.org/prop/direct/P691'), ('obj', 'ge129398')]
# [('pname', 'NUTS code'), ('p', 'http://www.wikidata.org/prop/direct/P605'), ('obj', 'IT')]
# [('pname', 'Namuwiki ID'), ('p', 'http://www.wikidata.org/prop/direct/P8885'), ('obj', '이탈리아')]
# [('pname', 'National Diet Library ID'), ('p', 'http://www.wikidata.org/prop/direct/P349'), ('obj', '00564289')]
# [('pname', 'National Library of Israel ID'), ('p', 'http://www.wikidata.org/prop/direct/P949'), ('obj', '000974608')]
# [('pname', 'New York Times topic ID'), ('p', 'http://www.wikidata.org/prop/direct/P3221'), ('obj', 'destination/italy')]
# [('pname', 'Nomisma ID'), ('p', 'http://www.wikidata.org/prop/direct/P2950'), ('obj', 'italian_republic')]
# [('pname', 'Nomisma ID'), ('p', 'http://www.wikidata.org/prop/direct/P2950'), ('obj', 'italy')]
# [('pname', 'OmegaWiki Defined Meaning'), ('p', 'http://www.wikidata.org/prop/direct/P1245'), ('obj', '5748')]
# [('pname', 'Omni topic ID'), ('p', 'http://www.wikidata.org/prop/direct/P3479'), ('obj', '147522ef37ba26fa349080740cbc56fce21227c1')]
# [('pname', 'OpenStreetMap relation ID'), ('p', 'http://www.wikidata.org/prop/direct/P402'), ('obj', '365331')]
# [('pname', 'OpenStreetMap zoom level'), ('p', 'http://www.wikidata.org/prop/direct/P6592'), ('obj', '5')]
# [('pname', 'Orthodox Encyclopedia ID'), ('p', 'http://www.wikidata.org/prop/direct/P5002'), ('obj', '1237717')]
# [('pname', 'Orthodox Encyclopedia ID'), ('p', 'http://www.wikidata.org/prop/direct/P5002'), ('obj', '2033728')]
# [('pname', 'Orthodox Encyclopedia ID'), ('p', 'http://www.wikidata.org/prop/direct/P5002'), ('obj', '2040510')]
# [('pname', 'Pontificia Università della Santa Croce ID'), ('p', 'http://www.wikidata.org/prop/direct/P5739'), ('obj', '40285')]
# [('pname', 'Portuguese National Library ID'), ('p', 'http://www.wikidata.org/prop/direct/P1005'), ('obj', '106839')]
# [('pname', 'Proleksis enciklopedija ID'), ('p', 'http://www.wikidata.org/prop/direct/P8349'), ('obj', '28389')]
# [('pname', 'Provenio UUID'), ('p', 'http://www.wikidata.org/prop/direct/P9223'), ('obj', '799e6ae0-961c-4472-a891-3b305bd5f798')]
# [('pname', 'Provenio UUID'), ('p', 'http://www.wikidata.org/prop/direct/P9223'), ('obj', '933edcbc-d695-4e05-b090-a2e39ed96e3f')]
# [('pname', 'Quora topic ID'), ('p', 'http://www.wikidata.org/prop/direct/P3417'), ('obj', 'Italy')]
# [('pname', 'Quora topic ID'), ('p', 'http://www.wikidata.org/prop/direct/P3417'), ('obj', 'Italya')]
# [('pname', 'RKD thesaurus ID'), ('p', 'http://www.wikidata.org/prop/direct/P8519'), ('obj', '287')]
# [('pname', 'SAPA ID'), ('p', 'http://www.wikidata.org/prop/direct/P8974'), ('obj', 'p/2521af2e-cd56-4dfb-b5ae-1f9872514c73')]
# [('pname', 'SHARE Catalogue author ID'), ('p', 'http://www.wikidata.org/prop/direct/P3987'), ('obj', '440885')]
# [('pname', 'SHARE Catalogue author ID'), ('p', 'http://www.wikidata.org/prop/direct/P3987'), ('obj', '423419')]
# [('pname', 'STW Thesaurus for Economics ID'), ('p', 'http://www.wikidata.org/prop/direct/P3911'), ('obj', '17039-2')]
# [('pname', 'Schoenberg Database of Manuscripts place ID'), ('p', 'http://www.wikidata.org/prop/direct/P9757'), ('obj', '7')]
# [('pname', 'Spanish Vikidia ID'), ('p', 'http://www.wikidata.org/prop/direct/P7827'), ('obj', 'Italia')]
# [('pname', 'SportsLogos.net team ID'), ('p', 'http://www.wikidata.org/prop/direct/P9122'), ('obj', '6176')]
# [('pname', 'Statoids ID'), ('p', 'http://www.wikidata.org/prop/direct/P3175'), ('obj', 'uit')]
# [('pname', 'Store norske leksikon ID'), ('p', 'http://www.wikidata.org/prop/direct/P4342'), ('obj', 'Italia')]
# [('pname', 'TDV İslam Ansiklopedisi ID'), ('p', 'http://www.wikidata.org/prop/direct/P7314'), ('obj', 'italya')]
# [('pname', 'TV Tropes identifier'), ('p', 'http://www.wikidata.org/prop/direct/P6839'), ('obj', 'UsefulNotes/Italy')]
# [('pname', 'TasteAtlas ID'), ('p', 'http://www.wikidata.org/prop/direct/P5456'), ('obj', 'italy')]
# [('pname', 'The Top Tens ID'), ('p', 'http://www.wikidata.org/prop/direct/P7157'), ('obj', '47')]
# [('pname', 'Treccani ID'), ('p', 'http://www.wikidata.org/prop/direct/P3365'), ('obj', 'italia')]
# [('pname', "Treccani's Dizionario di Storia ID"), ('p', 'http://www.wikidata.org/prop/direct/P6404'), ('obj', 'italia')]
# [('pname', 'U.S. National Archives Identifier'), ('p', 'http://www.wikidata.org/prop/direct/P1225'), ('obj', '10035812')]
# [('pname', 'U.S. National Archives Identifier'), ('p', 'http://www.wikidata.org/prop/direct/P1225'), ('obj', '10041770')]
# [('pname', 'UIC alphabetical country code'), ('p', 'http://www.wikidata.org/prop/direct/P2981'), ('obj', 'I')]
# [('pname', 'UIC numerical country code'), ('p', 'http://www.wikidata.org/prop/direct/P2982'), ('obj', '83')]
# [('pname', 'UK Parliament thesaurus ID'), ('p', 'http://www.wikidata.org/prop/direct/P4527'), ('obj', '11075')]
# [('pname', 'UNESCO Thesaurus ID'), ('p', 'http://www.wikidata.org/prop/direct/P3916'), ('obj', 'concept910')]
# [('pname', 'Unicode character'), ('p', 'http://www.wikidata.org/prop/direct/P487'), ('obj', '🇮🇹')]
# [('pname', 'VAT-rate'), ('p', 'http://www.wikidata.org/prop/direct/P2855'), ('obj', '22')]
# [('pname', 'VIAF ID'), ('p', 'http://www.wikidata.org/prop/direct/P214'), ('obj', '152361066')]
# [('pname', 'WIPO ST.3'), ('p', 'http://www.wikidata.org/prop/direct/P3068'), ('obj', 'IT')]
# [('pname', "Who's on First ID"), ('p', 'http://www.wikidata.org/prop/direct/P6766'), ('obj', '85633253')]
# [('pname', 'Wikimedia outline'), ('oname', 'outline of Italy'), ('p', 'http://www.wikidata.org/prop/direct/P5125'), ('obj', 'http://www.wikidata.org/entity/Q7112307')]
# [('pname', 'WordNet 3.1 Synset ID'), ('p', 'http://www.wikidata.org/prop/direct/P8814'), ('obj', '08819530-n')]
# [('pname', 'World Encyclopedia of Puppetry Arts ID'), ('p', 'http://www.wikidata.org/prop/direct/P7012'), ('obj', 'italy')]
# [('pname', 'WorldCat Identities ID'), ('p', 'http://www.wikidata.org/prop/direct/P7859'), ('obj', 'lccn-n79021783')]
# [('pname', 'YSA ID'), ('p', 'http://www.wikidata.org/prop/direct/P6293'), ('obj', 'Y105111')]
# [('pname', 'YSO ID'), ('p', 'http://www.wikidata.org/prop/direct/P2347'), ('obj', '105111')]
# [('pname', 'Yle topic ID'), ('p', 'http://www.wikidata.org/prop/direct/P8309'), ('obj', '18-177017')]
# [('pname', 'Zhihu topic ID'), ('p', 'http://www.wikidata.org/prop/direct/P3553'), ('obj', '19571981')]
# [('pname', 'age of majority'), ('p', 'http://www.wikidata.org/prop/direct/P2997'), ('obj', '18')]
# [('pname', 'anthem'), ('oname', 'Il Canto degli Italiani'), ('p', 'http://www.wikidata.org/prop/direct/P85'), ('obj', 'http://www.wikidata.org/entity/Q187')]
# [('pname', 'archINFORM location ID'), ('p', 'http://www.wikidata.org/prop/direct/P5573'), ('obj', '2996')]
# [('pname', 'area'), ('p', 'http://www.wikidata.org/prop/direct/P2046'), ('obj', '301338')]
# [('pname', 'basic form of government'), ('oname', 'parliamentary republic'), ('p', 'http://www.wikidata.org/prop/direct/P122'), ('obj', 'http://www.wikidata.org/entity/Q4198907')]
# [('pname', 'capital'), ('oname', 'Rome'), ('p', 'http://www.wikidata.org/prop/direct/P36'), ('obj', 'http://www.wikidata.org/entity/Q220')]
# [('pname', 'category for films shot at this location'), ('oname', 'Category:Films shot in Italy'), ('p', 'http://www.wikidata.org/prop/direct/P1740'), ('obj', 'http://www.wikidata.org/entity/Q7140608')]
# [('pname', 'category for maps'), ('oname', 'Category:Maps of Italy'), ('p', 'http://www.wikidata.org/prop/direct/P7867'), ('obj', 'http://www.wikidata.org/entity/Q8607398')]
# [('pname', 'category for people who died here'), ('oname', 'Category:Deaths in Italy'), ('p', 'http://www.wikidata.org/prop/direct/P1465'), ('obj', 'http://www.wikidata.org/entity/Q6334620')]
# [('pname', 'category for people born here'), ('oname', 'Category:Births in Italy'), ('p', 'http://www.wikidata.org/prop/direct/P1464'), ('obj', 'http://www.wikidata.org/entity/Q9229082')]
# [('pname', 'category of associated people'), ('oname', 'Category:Italian people'), ('p', 'http://www.wikidata.org/prop/direct/P1792'), ('obj', 'http://www.wikidata.org/entity/Q3919890')]
# [('pname', 'category of people buried here'), ('oname', 'Category:Burials in Italy'), ('p', 'http://www.wikidata.org/prop/direct/P1791'), ('obj', 'http://www.wikidata.org/entity/Q8328654')]
# [('pname', 'coat of arms'), ('oname', 'emblem of Italy'), ('p', 'http://www.wikidata.org/prop/direct/P237'), ('obj', 'http://www.wikidata.org/entity/Q199432')]
# [('pname', 'coat of arms image'), ('p', 'http://www.wikidata.org/prop/direct/P94'), ('obj', 'http://commons.wikimedia.org/wiki/Special:FilePath/Emblem%20of%20Italy.svg')]
# [('pname', 'compulsory education (maximum age)'), ('p', 'http://www.wikidata.org/prop/direct/P3271'), ('obj', '16')]
# [('pname', 'compulsory education (minimum age)'), ('p', 'http://www.wikidata.org/prop/direct/P3270'), ('obj', '6')]
# [('pname', 'contains administrative territorial entity'), ('oname', 'Tuscany'), ('p', 'http://www.wikidata.org/prop/direct/P150'), ('obj', 'http://www.wikidata.org/entity/Q1273')]
# [('pname', 'contains administrative territorial entity'), ('oname', 'Trentino-South Tyrol'), ('p', 'http://www.wikidata.org/prop/direct/P150'), ('obj', 'http://www.wikidata.org/entity/Q1237')]
# [('pname', 'contains administrative territorial entity'), ('oname', 'Lombardy'), ('p', 'http://www.wikidata.org/prop/direct/P150'), ('obj', 'http://www.wikidata.org/entity/Q1210')]
# [('pname', 'contains administrative territorial entity'), ('oname', 'Piedmont'), ('p', 'http://www.wikidata.org/prop/direct/P150'), ('obj', 'http://www.wikidata.org/entity/Q1216')]
# [('pname', 'contains administrative territorial entity'), ('oname', 'Aosta Valley'), ('p', 'http://www.wikidata.org/prop/direct/P150'), ('obj', 'http://www.wikidata.org/entity/Q1222')]
# [('pname', 'contains administrative territorial entity'), ('oname', 'Veneto'), ('p', 'http://www.wikidata.org/prop/direct/P150'), ('obj', 'http://www.wikidata.org/entity/Q1243')]
# [('pname', 'contains administrative territorial entity'), ('oname', 'Emilia-Romagna'), ('p', 'http://www.wikidata.org/prop/direct/P150'), ('obj', 'http://www.wikidata.org/entity/Q1263')]
# [('pname', 'contains administrative territorial entity'), ('oname', 'Basilicata'), ('p', 'http://www.wikidata.org/prop/direct/P150'), ('obj', 'http://www.wikidata.org/entity/Q1452')]
# [('pname', 'contains administrative territorial entity'), ('oname', 'Friuli-Venezia Giulia'), ('p', 'http://www.wikidata.org/prop/direct/P150'), ('obj', 'http://www.wikidata.org/entity/Q1250')]
# [('pname', 'contains administrative territorial entity'), ('oname', 'Marche'), ('p', 'http://www.wikidata.org/prop/direct/P150'), ('obj', 'http://www.wikidata.org/entity/Q1279')]
# [('pname', 'contains administrative territorial entity'), ('oname', 'Umbria'), ('p', 'http://www.wikidata.org/prop/direct/P150'), ('obj', 'http://www.wikidata.org/entity/Q1280')]
# [('pname', 'contains administrative territorial entity'), ('oname', 'Abruzzo'), ('p', 'http://www.wikidata.org/prop/direct/P150'), ('obj', 'http://www.wikidata.org/entity/Q1284')]
# [('pname', 'contains administrative territorial entity'), ('oname', 'Campania'), ('p', 'http://www.wikidata.org/prop/direct/P150'), ('obj', 'http://www.wikidata.org/entity/Q1438')]
# [('pname', 'contains administrative territorial entity'), ('oname', 'Apulia'), ('p', 'http://www.wikidata.org/prop/direct/P150'), ('obj', 'http://www.wikidata.org/entity/Q1447')]
# [('pname', 'contains administrative territorial entity'), ('oname', 'Calabria'), ('p', 'http://www.wikidata.org/prop/direct/P150'), ('obj', 'http://www.wikidata.org/entity/Q1458')]
# [('pname', 'contains administrative territorial entity'), ('oname', 'Sicily'), ('p', 'http://www.wikidata.org/prop/direct/P150'), ('obj', 'http://www.wikidata.org/entity/Q1460')]
# [('pname', 'contains administrative territorial entity'), ('oname', 'Sardinia'), ('p', 'http://www.wikidata.org/prop/direct/P150'), ('obj', 'http://www.wikidata.org/entity/Q1462')]
# [('pname', 'contains administrative territorial entity'), ('oname', 'Liguria'), ('p', 'http://www.wikidata.org/prop/direct/P150'), ('obj', 'http://www.wikidata.org/entity/Q1256')]
# [('pname', 'contains administrative territorial entity'), ('oname', 'Molise'), ('p', 'http://www.wikidata.org/prop/direct/P150'), ('obj', 'http://www.wikidata.org/entity/Q1443')]
# [('pname', 'contains administrative territorial entity'), ('oname', 'Lazio'), ('p', 'http://www.wikidata.org/prop/direct/P150'), ('obj', 'http://www.wikidata.org/entity/Q1282')]
# [('pname', 'continent'), ('oname', 'Europe'), ('p', 'http://www.wikidata.org/prop/direct/P30'), ('obj', 'http://www.wikidata.org/entity/Q46')]
# [('pname', 'country'), ('oname', 'Italy'), ('p', 'http://www.wikidata.org/prop/direct/P17'), ('obj', 'http://www.wikidata.org/entity/Q38')]
# [('pname', 'country calling code'), ('p', 'http://www.wikidata.org/prop/direct/P474'), ('obj', '+39')]
# [('pname', 'culture'), ('oname', 'culture of Italy'), ('p', 'http://www.wikidata.org/prop/direct/P2596'), ('obj', 'http://www.wikidata.org/entity/Q1992919')]
# [('pname', 'currency'), ('oname', 'euro'), ('p', 'http://www.wikidata.org/prop/direct/P38'), ('obj', 'http://www.wikidata.org/entity/Q4916')]
# [('pname', 'demographics of topic'), ('oname', 'demographics of Italy'), ('p', 'http://www.wikidata.org/prop/direct/P9241'), ('obj', 'http://www.wikidata.org/entity/Q1800338')]
# [('pname', 'demonym'), ('p', 'http://www.wikidata.org/prop/direct/P1549'), ('obj', 'Italian')]
# [('pname', 'described by source'), ('oname', 'Small Brockhaus and Efron Encyclopedic Dictionary'), ('p', 'http://www.wikidata.org/prop/direct/P1343'), ('obj', 'http://www.wikidata.org/entity/Q19180675')]
# [('pname', 'described by source'), ('oname', 'Armenian Soviet Encyclopedia'), ('p', 'http://www.wikidata.org/prop/direct/P1343'), ('obj', 'http://www.wikidata.org/entity/Q2657718')]
# [('pname', 'described by source'), ('oname', 'Catholic Encyclopedia'), ('p', 'http://www.wikidata.org/prop/direct/P1343'), ('obj', 'http://www.wikidata.org/entity/Q302556')]
# [('pname', 'described by source'), ('oname', 'Bible Encyclopedia of Archimandrite Nicephorus'), ('p', 'http://www.wikidata.org/prop/direct/P1343'), ('obj', 'http://www.wikidata.org/entity/Q4086271')]
# [('pname', 'described by source'), ('oname', 'Sytin Military Encyclopedia'), ('p', 'http://www.wikidata.org/prop/direct/P1343'), ('obj', 'http://www.wikidata.org/entity/Q4114391')]
# [('pname', 'described by source'), ('oname', 'Jewish Encyclopedia of Brockhaus and Efron'), ('p', 'http://www.wikidata.org/prop/direct/P1343'), ('obj', 'http://www.wikidata.org/entity/Q4173137')]
# [('pname', 'described by source'), ('oname', 'Brockhaus and Efron Encyclopedic Dictionary'), ('p', 'http://www.wikidata.org/prop/direct/P1343'), ('obj', 'http://www.wikidata.org/entity/Q602358')]
# [('pname', 'described by source'), ('oname', 'Encyclopædia Britannica 11th edition'), ('p', 'http://www.wikidata.org/prop/direct/P1343'), ('obj', 'http://www.wikidata.org/entity/Q867541')]
# [('pname', 'diplomatic relation'), ('oname', 'Libya'), ('p', 'http://www.wikidata.org/prop/direct/P530'), ('obj', 'http://www.wikidata.org/entity/Q1016')]
# [('pname', 'diplomatic relation'), ('oname', 'Somalia'), ('p', 'http://www.wikidata.org/prop/direct/P530'), ('obj', 'http://www.wikidata.org/entity/Q1045')]
# [('pname', 'diplomatic relation'), ('oname', 'Kenya'), ('p', 'http://www.wikidata.org/prop/direct/P530'), ('obj', 'http://www.wikidata.org/entity/Q114')]
# [('pname', 'diplomatic relation'), ('oname', 'Ethiopia'), ('p', 'http://www.wikidata.org/prop/direct/P530'), ('obj', 'http://www.wikidata.org/entity/Q115')]
# [('pname', 'diplomatic relation'), ('oname', 'Kosovo'), ('p', 'http://www.wikidata.org/prop/direct/P530'), ('obj', 'http://www.wikidata.org/entity/Q1246')]
# [('pname', 'diplomatic relation'), ('oname', 'France'), ('p', 'http://www.wikidata.org/prop/direct/P530'), ('obj', 'http://www.wikidata.org/entity/Q142')]
# [('pname', 'diplomatic relation'), ('oname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P530'), ('obj', 'http://www.wikidata.org/entity/Q145')]
# [('pname', 'diplomatic relation'), ('oname', "People's Republic of China"), ('p', 'http://www.wikidata.org/prop/direct/P530'), ('obj', 'http://www.wikidata.org/entity/Q148')]
# [('pname', 'diplomatic relation'), ('oname', 'Brazil'), ('p', 'http://www.wikidata.org/prop/direct/P530'), ('obj', 'http://www.wikidata.org/entity/Q155')]
# [('pname', 'diplomatic relation'), ('oname', 'Russia'), ('p', 'http://www.wikidata.org/prop/direct/P530'), ('obj', 'http://www.wikidata.org/entity/Q159')]
# [('pname', 'diplomatic relation'), ('oname', 'Holy See'), ('p', 'http://www.wikidata.org/prop/direct/P530'), ('obj', 'http://www.wikidata.org/entity/Q159583')]
# [('pname', 'diplomatic relation'), ('oname', 'Canada'), ('p', 'http://www.wikidata.org/prop/direct/P530'), ('obj', 'http://www.wikidata.org/entity/Q16')]
# [('pname', 'diplomatic relation'), ('oname', 'Japan'), ('p', 'http://www.wikidata.org/prop/direct/P530'), ('obj', 'http://www.wikidata.org/entity/Q17')]
# [('pname', 'diplomatic relation'), ('oname', 'Germany'), ('p', 'http://www.wikidata.org/prop/direct/P530'), ('obj', 'http://www.wikidata.org/entity/Q183')]
# [('pname', 'diplomatic relation'), ('oname', 'Belarus'), ('p', 'http://www.wikidata.org/prop/direct/P530'), ('obj', 'http://www.wikidata.org/entity/Q184')]
# [('pname', 'diplomatic relation'), ('oname', 'Iceland'), ('p', 'http://www.wikidata.org/prop/direct/P530'), ('obj', 'http://www.wikidata.org/entity/Q189')]
# [('pname', 'diplomatic relation'), ('oname', 'Estonia'), ('p', 'http://www.wikidata.org/prop/direct/P530'), ('obj', 'http://www.wikidata.org/entity/Q191')]
# [('pname', 'diplomatic relation'), ('oname', 'Norway'), ('p', 'http://www.wikidata.org/prop/direct/P530'), ('obj', 'http://www.wikidata.org/entity/Q20')]
# [('pname', 'diplomatic relation'), ('oname', 'Latvia'), ('p', 'http://www.wikidata.org/prop/direct/P530'), ('obj', 'http://www.wikidata.org/entity/Q211')]
# [('pname', 'diplomatic relation'), ('oname', 'Ukraine'), ('p', 'http://www.wikidata.org/prop/direct/P530'), ('obj', 'http://www.wikidata.org/entity/Q212')]
# [('pname', 'diplomatic relation'), ('oname', 'Czech Republic'), ('p', 'http://www.wikidata.org/prop/direct/P530'), ('obj', 'http://www.wikidata.org/entity/Q213')]
# [('pname', 'diplomatic relation'), ('oname', 'Slovakia'), ('p', 'http://www.wikidata.org/prop/direct/P530'), ('obj', 'http://www.wikidata.org/entity/Q214')]
# [('pname', 'diplomatic relation'), ('oname', 'Slovenia'), ('p', 'http://www.wikidata.org/prop/direct/P530'), ('obj', 'http://www.wikidata.org/entity/Q215')]
# [('pname', 'diplomatic relation'), ('oname', 'Moldova'), ('p', 'http://www.wikidata.org/prop/direct/P530'), ('obj', 'http://www.wikidata.org/entity/Q217')]
# [('pname', 'diplomatic relation'), ('oname', 'Romania'), ('p', 'http://www.wikidata.org/prop/direct/P530'), ('obj', 'http://www.wikidata.org/entity/Q218')]
# [('pname', 'diplomatic relation'), ('oname', 'Bulgaria'), ('p', 'http://www.wikidata.org/prop/direct/P530'), ('obj', 'http://www.wikidata.org/entity/Q219')]
# [('pname', 'diplomatic relation'), ('oname', 'North Macedonia'), ('p', 'http://www.wikidata.org/prop/direct/P530'), ('obj', 'http://www.wikidata.org/entity/Q221')]
# [('pname', 'diplomatic relation'), ('oname', 'Albania'), ('p', 'http://www.wikidata.org/prop/direct/P530'), ('obj', 'http://www.wikidata.org/entity/Q222')]
# [('pname', 'diplomatic relation'), ('oname', 'Croatia'), ('p', 'http://www.wikidata.org/prop/direct/P530'), ('obj', 'http://www.wikidata.org/entity/Q224')]
# [('pname', 'diplomatic relation'), ('oname', 'Bosnia and Herzegovina'), ('p', 'http://www.wikidata.org/prop/direct/P530'), ('obj', 'http://www.wikidata.org/entity/Q225')]
# [('pname', 'diplomatic relation'), ('oname', 'Azerbaijan'), ('p', 'http://www.wikidata.org/prop/direct/P530'), ('obj', 'http://www.wikidata.org/entity/Q227')]
# [('pname', 'diplomatic relation'), ('oname', 'Andorra'), ('p', 'http://www.wikidata.org/prop/direct/P530'), ('obj', 'http://www.wikidata.org/entity/Q228')]
# [('pname', 'diplomatic relation'), ('oname', 'Cyprus'), ('p', 'http://www.wikidata.org/prop/direct/P530'), ('obj', 'http://www.wikidata.org/entity/Q229')]
# [('pname', 'diplomatic relation'), ('oname', 'Georgia'), ('p', 'http://www.wikidata.org/prop/direct/P530'), ('obj', 'http://www.wikidata.org/entity/Q230')]
# [('pname', 'diplomatic relation'), ('oname', 'Malta'), ('p', 'http://www.wikidata.org/prop/direct/P530'), ('obj', 'http://www.wikidata.org/entity/Q233')]
# [('pname', 'diplomatic relation'), ('oname', 'Monaco'), ('p', 'http://www.wikidata.org/prop/direct/P530'), ('obj', 'http://www.wikidata.org/entity/Q235')]
# [('pname', 'diplomatic relation'), ('oname', 'Montenegro'), ('p', 'http://www.wikidata.org/prop/direct/P530'), ('obj', 'http://www.wikidata.org/entity/Q236')]
# [('pname', 'diplomatic relation'), ('oname', 'San Marino'), ('p', 'http://www.wikidata.org/prop/direct/P530'), ('obj', 'http://www.wikidata.org/entity/Q238')]
# [('pname', 'diplomatic relation'), ('oname', 'Indonesia'), ('p', 'http://www.wikidata.org/prop/direct/P530'), ('obj', 'http://www.wikidata.org/entity/Q252')]
# [('pname', 'diplomatic relation'), ('oname', 'South Africa'), ('p', 'http://www.wikidata.org/prop/direct/P530'), ('obj', 'http://www.wikidata.org/entity/Q258')]
# [('pname', 'diplomatic relation'), ('oname', 'Ireland'), ('p', 'http://www.wikidata.org/prop/direct/P530'), ('obj', 'http://www.wikidata.org/entity/Q27')]
# [('pname', 'diplomatic relation'), ('oname', 'Hungary'), ('p', 'http://www.wikidata.org/prop/direct/P530'), ('obj', 'http://www.wikidata.org/entity/Q28')]
# [('pname', 'diplomatic relation'), ('oname', 'Spain'), ('p', 'http://www.wikidata.org/prop/direct/P530'), ('obj', 'http://www.wikidata.org/entity/Q29')]
# [('pname', 'diplomatic relation'), ('oname', 'Chile'), ('p', 'http://www.wikidata.org/prop/direct/P530'), ('obj', 'http://www.wikidata.org/entity/Q298')]
# [('pname', 'diplomatic relation'), ('oname', 'United States of America'), ('p', 'http://www.wikidata.org/prop/direct/P530'), ('obj', 'http://www.wikidata.org/entity/Q30')]
# [('pname', 'diplomatic relation'), ('oname', 'Belgium'), ('p', 'http://www.wikidata.org/prop/direct/P530'), ('obj', 'http://www.wikidata.org/entity/Q31')]
# [('pname', 'diplomatic relation'), ('oname', 'Luxembourg'), ('p', 'http://www.wikidata.org/prop/direct/P530'), ('obj', 'http://www.wikidata.org/entity/Q32')]
# [('pname', 'diplomatic relation'), ('oname', 'Finland'), ('p', 'http://www.wikidata.org/prop/direct/P530'), ('obj', 'http://www.wikidata.org/entity/Q33')]
# [('pname', 'diplomatic relation'), ('oname', 'Sweden'), ('p', 'http://www.wikidata.org/prop/direct/P530'), ('obj', 'http://www.wikidata.org/entity/Q34')]
# [('pname', 'diplomatic relation'), ('oname', 'Liechtenstein'), ('p', 'http://www.wikidata.org/prop/direct/P530'), ('obj', 'http://www.wikidata.org/entity/Q347')]
# [('pname', 'diplomatic relation'), ('oname', 'Denmark'), ('p', 'http://www.wikidata.org/prop/direct/P530'), ('obj', 'http://www.wikidata.org/entity/Q35')]
# [('pname', 'diplomatic relation'), ('oname', 'Poland'), ('p', 'http://www.wikidata.org/prop/direct/P530'), ('obj', 'http://www.wikidata.org/entity/Q36')]
# [('pname', 'diplomatic relation'), ('oname', 'Yugoslavia'), ('p', 'http://www.wikidata.org/prop/direct/P530'), ('obj', 'http://www.wikidata.org/entity/Q36704')]
# [('pname', 'diplomatic relation'), ('oname', 'Lithuania'), ('p', 'http://www.wikidata.org/prop/direct/P530'), ('obj', 'http://www.wikidata.org/entity/Q37')]
# [('pname', 'diplomatic relation'), ('oname', 'Switzerland'), ('p', 'http://www.wikidata.org/prop/direct/P530'), ('obj', 'http://www.wikidata.org/entity/Q39')]
# [('pname', 'diplomatic relation'), ('oname', 'Armenia'), ('p', 'http://www.wikidata.org/prop/direct/P530'), ('obj', 'http://www.wikidata.org/entity/Q399')]
# [('pname', 'diplomatic relation'), ('oname', 'Austria'), ('p', 'http://www.wikidata.org/prop/direct/P530'), ('obj', 'http://www.wikidata.org/entity/Q40')]
# [('pname', 'diplomatic relation'), ('oname', 'Serbia'), ('p', 'http://www.wikidata.org/prop/direct/P530'), ('obj', 'http://www.wikidata.org/entity/Q403')]
# [('pname', 'diplomatic relation'), ('oname', 'Australia'), ('p', 'http://www.wikidata.org/prop/direct/P530'), ('obj', 'http://www.wikidata.org/entity/Q408')]
# [('pname', 'diplomatic relation'), ('oname', 'Greece'), ('p', 'http://www.wikidata.org/prop/direct/P530'), ('obj', 'http://www.wikidata.org/entity/Q41')]
# [('pname', 'diplomatic relation'), ('oname', 'Argentina'), ('p', 'http://www.wikidata.org/prop/direct/P530'), ('obj', 'http://www.wikidata.org/entity/Q414')]
# [('pname', 'diplomatic relation'), ('oname', 'Peru'), ('p', 'http://www.wikidata.org/prop/direct/P530'), ('obj', 'http://www.wikidata.org/entity/Q419')]
# [('pname', 'diplomatic relation'), ('oname', 'North Korea'), ('p', 'http://www.wikidata.org/prop/direct/P530'), ('obj', 'http://www.wikidata.org/entity/Q423')]
# [('pname', 'diplomatic relation'), ('oname', 'Turkey'), ('p', 'http://www.wikidata.org/prop/direct/P530'), ('obj', 'http://www.wikidata.org/entity/Q43')]
# [('pname', 'diplomatic relation'), ('oname', 'Portugal'), ('p', 'http://www.wikidata.org/prop/direct/P530'), ('obj', 'http://www.wikidata.org/entity/Q45')]
# [('pname', 'diplomatic relation'), ('oname', 'Netherlands'), ('p', 'http://www.wikidata.org/prop/direct/P530'), ('obj', 'http://www.wikidata.org/entity/Q55')]
# [('pname', 'diplomatic relation'), ('oname', 'New Zealand'), ('p', 'http://www.wikidata.org/prop/direct/P530'), ('obj', 'http://www.wikidata.org/entity/Q664')]
# [('pname', 'diplomatic relation'), ('oname', 'India'), ('p', 'http://www.wikidata.org/prop/direct/P530'), ('obj', 'http://www.wikidata.org/entity/Q668')]
# [('pname', 'diplomatic relation'), ('oname', 'Paraguay'), ('p', 'http://www.wikidata.org/prop/direct/P530'), ('obj', 'http://www.wikidata.org/entity/Q733')]
# [('pname', 'diplomatic relation'), ('oname', 'Colombia'), ('p', 'http://www.wikidata.org/prop/direct/P530'), ('obj', 'http://www.wikidata.org/entity/Q739')]
# [('pname', 'diplomatic relation'), ('oname', 'Uruguay'), ('p', 'http://www.wikidata.org/prop/direct/P530'), ('obj', 'http://www.wikidata.org/entity/Q77')]
# [('pname', 'diplomatic relation'), ('oname', 'Egypt'), ('p', 'http://www.wikidata.org/prop/direct/P530'), ('obj', 'http://www.wikidata.org/entity/Q79')]
# [('pname', 'diplomatic relation'), ('oname', 'Iran'), ('p', 'http://www.wikidata.org/prop/direct/P530'), ('obj', 'http://www.wikidata.org/entity/Q794')]
# [('pname', 'diplomatic relation'), ('oname', 'Iraq'), ('p', 'http://www.wikidata.org/prop/direct/P530'), ('obj', 'http://www.wikidata.org/entity/Q796')]
# [('pname', 'diplomatic relation'), ('oname', 'Israel'), ('p', 'http://www.wikidata.org/prop/direct/P530'), ('obj', 'http://www.wikidata.org/entity/Q801')]
# [('pname', 'diplomatic relation'), ('oname', 'Yemen'), ('p', 'http://www.wikidata.org/prop/direct/P530'), ('obj', 'http://www.wikidata.org/entity/Q805')]
# [('pname', 'diplomatic relation'), ('oname', 'Lebanon'), ('p', 'http://www.wikidata.org/prop/direct/P530'), ('obj', 'http://www.wikidata.org/entity/Q822')]
# [('pname', 'diplomatic relation'), ('oname', 'Pakistan'), ('p', 'http://www.wikidata.org/prop/direct/P530'), ('obj', 'http://www.wikidata.org/entity/Q843')]
# [('pname', 'diplomatic relation'), ('oname', 'Taiwan'), ('p', 'http://www.wikidata.org/prop/direct/P530'), ('obj', 'http://www.wikidata.org/entity/Q865')]
# [('pname', 'diplomatic relation'), ('oname', 'Thailand'), ('p', 'http://www.wikidata.org/prop/direct/P530'), ('obj', 'http://www.wikidata.org/entity/Q869')]
# [('pname', 'diplomatic relation'), ('oname', 'Vietnam'), ('p', 'http://www.wikidata.org/prop/direct/P530'), ('obj', 'http://www.wikidata.org/entity/Q881')]
# [('pname', 'diplomatic relation'), ('oname', 'South Korea'), ('p', 'http://www.wikidata.org/prop/direct/P530'), ('obj', 'http://www.wikidata.org/entity/Q884')]
# [('pname', 'diplomatic relation'), ('oname', 'Afghanistan'), ('p', 'http://www.wikidata.org/prop/direct/P530'), ('obj', 'http://www.wikidata.org/entity/Q889')]
# [('pname', 'diplomatic relation'), ('oname', 'Bangladesh'), ('p', 'http://www.wikidata.org/prop/direct/P530'), ('obj', 'http://www.wikidata.org/entity/Q902')]
# [('pname', 'diplomatic relation'), ('oname', 'Philippines'), ('p', 'http://www.wikidata.org/prop/direct/P530'), ('obj', 'http://www.wikidata.org/entity/Q928')]
# [('pname', 'diplomatic relation'), ('oname', 'Tunisia'), ('p', 'http://www.wikidata.org/prop/direct/P530'), ('obj', 'http://www.wikidata.org/entity/Q948')]
# [('pname', 'diplomatic relation'), ('oname', 'Mexico'), ('p', 'http://www.wikidata.org/prop/direct/P530'), ('obj', 'http://www.wikidata.org/entity/Q96')]
# [('pname', 'driving side'), ('oname', 'right'), ('p', 'http://www.wikidata.org/prop/direct/P1622'), ('obj', 'http://www.wikidata.org/entity/Q14565199')]
# [('pname', 'economy of topic'), ('oname', 'economy of Italy'), ('p', 'http://www.wikidata.org/prop/direct/P8744'), ('obj', 'http://www.wikidata.org/entity/Q720060')]
# [('pname', 'edition humboldt digital ID'), ('p', 'http://www.wikidata.org/prop/direct/P8826'), ('obj', 'H0006750')]
# [('pname', 'electrical plug type'), ('oname', 'Schuko'), ('p', 'http://www.wikidata.org/prop/direct/P2853'), ('obj', 'http://www.wikidata.org/entity/Q1123613')]
# [('pname', 'electrical plug type'), ('oname', 'Europlug'), ('p', 'http://www.wikidata.org/prop/direct/P2853'), ('obj', 'http://www.wikidata.org/entity/Q1378312')]
# [('pname', 'electrical plug type'), ('oname', 'Type L'), ('p', 'http://www.wikidata.org/prop/direct/P2853'), ('obj', 'http://www.wikidata.org/entity/Q1520890')]
# [('pname', 'emergency telephone number'), ('oname', '112'), ('p', 'http://www.wikidata.org/prop/direct/P2852'), ('obj', 'http://www.wikidata.org/entity/Q1061257')]
# [('pname', 'emergency telephone number'), ('oname', '113'), ('p', 'http://www.wikidata.org/prop/direct/P2852'), ('obj', 'http://www.wikidata.org/entity/Q25648804')]
# [('pname', 'emergency telephone number'), ('oname', '115'), ('p', 'http://www.wikidata.org/prop/direct/P2852'), ('obj', 'http://www.wikidata.org/entity/Q25648805')]
# [('pname', 'emergency telephone number'), ('oname', '118'), ('p', 'http://www.wikidata.org/prop/direct/P2852'), ('obj', 'http://www.wikidata.org/entity/Q11185210')]
# [('pname', 'executive body'), ('oname', 'Government of Italy'), ('p', 'http://www.wikidata.org/prop/direct/P208'), ('obj', 'http://www.wikidata.org/entity/Q3773971')]
# [('pname', 'flag'), ('oname', 'flag of Italy'), ('p', 'http://www.wikidata.org/prop/direct/P163'), ('obj', 'http://www.wikidata.org/entity/Q42876')]
# [('pname', 'flag image'), ('p', 'http://www.wikidata.org/prop/direct/P41'), ('obj', 'http://commons.wikimedia.org/wiki/Special:FilePath/Flag%20of%20Italy.svg')]
# [('pname', 'follows'), ('oname', 'Kingdom of Italy'), ('p', 'http://www.wikidata.org/prop/direct/P155'), ('obj', 'http://www.wikidata.org/entity/Q172579')]
# [('pname', 'geography of topic'), ('oname', 'geography of Italy'), ('p', 'http://www.wikidata.org/prop/direct/P2633'), ('obj', 'http://www.wikidata.org/entity/Q216989')]
# [('pname', 'geoshape'), ('p', 'http://www.wikidata.org/prop/direct/P3896'), ('obj', 'http://commons.wikimedia.org/data/main/Data:Italia.map')]
# [('pname', 'has quality'), ('oname', 'free country'), ('p', 'http://www.wikidata.org/prop/direct/P1552'), ('obj', 'http://www.wikidata.org/entity/Q3174312')]
# [('pname', 'head of government'), ('oname', 'Mario Draghi'), ('p', 'http://www.wikidata.org/prop/direct/P6'), ('obj', 'http://www.wikidata.org/entity/Q294460')]
# [('pname', 'head of state'), ('oname', 'Sergio Mattarella'), ('p', 'http://www.wikidata.org/prop/direct/P35'), ('obj', 'http://www.wikidata.org/entity/Q3956186')]
# [('pname', 'highest judicial authority'), ('oname', 'Supreme Court of Cassation'), ('p', 'http://www.wikidata.org/prop/direct/P209'), ('obj', 'http://www.wikidata.org/entity/Q1135541')]
# [('pname', 'highest point'), ('oname', 'Mont Blanc'), ('p', 'http://www.wikidata.org/prop/direct/P610'), ('obj', 'http://www.wikidata.org/entity/Q583')]
# [('pname', 'history of topic'), ('oname', 'history of Italy'), ('p', 'http://www.wikidata.org/prop/direct/P2184'), ('obj', 'http://www.wikidata.org/entity/Q7791')]
# [('pname', 'iDAI.gazetteer ID'), ('p', 'http://www.wikidata.org/prop/direct/P8217'), ('obj', '2309807')]
# [('pname', 'iNaturalist place ID'), ('p', 'http://www.wikidata.org/prop/direct/P7471'), ('obj', '6973')]
# [('pname', 'inception'), ('p', 'http://www.wikidata.org/prop/direct/P571'), ('obj', '1946-06-18T00:00:00Z')]
# [('pname', 'instance of'), ('oname', 'sovereign state'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('obj', 'http://www.wikidata.org/entity/Q3624078')]
# [('pname', 'instance of'), ('oname', 'country'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('obj', 'http://www.wikidata.org/entity/Q6256')]
# [('pname', 'language used'), ('oname', 'Sicilian'), ('p', 'http://www.wikidata.org/prop/direct/P2936'), ('obj', 'http://www.wikidata.org/entity/Q33973')]
# [('pname', 'language used'), ('oname', 'Neapolitan'), ('p', 'http://www.wikidata.org/prop/direct/P2936'), ('obj', 'http://www.wikidata.org/entity/Q33845')]
# [('pname', 'language used'), ('oname', 'Friulian'), ('p', 'http://www.wikidata.org/prop/direct/P2936'), ('obj', 'http://www.wikidata.org/entity/Q33441')]
# [('pname', 'language used'), ('oname', 'French'), ('p', 'http://www.wikidata.org/prop/direct/P2936'), ('obj', 'http://www.wikidata.org/entity/Q150')]
# [('pname', 'language used'), ('oname', 'German'), ('p', 'http://www.wikidata.org/prop/direct/P2936'), ('obj', 'http://www.wikidata.org/entity/Q188')]
# [('pname', 'language used'), ('oname', 'Sardinian'), ('p', 'http://www.wikidata.org/prop/direct/P2936'), ('obj', 'http://www.wikidata.org/entity/Q33976')]
# [('pname', 'language used'), ('oname', 'Italian'), ('p', 'http://www.wikidata.org/prop/direct/P2936'), ('obj', 'http://www.wikidata.org/entity/Q652')]
# [('pname', 'language used'), ('oname', 'Slovene'), ('p', 'http://www.wikidata.org/prop/direct/P2936'), ('obj', 'http://www.wikidata.org/entity/Q9063')]
# [('pname', 'language used'), ('oname', 'Emilian'), ('p', 'http://www.wikidata.org/prop/direct/P2936'), ('obj', 'http://www.wikidata.org/entity/Q1057898')]
# [('pname', 'language used'), ('oname', 'Occitan'), ('p', 'http://www.wikidata.org/prop/direct/P2936'), ('obj', 'http://www.wikidata.org/entity/Q14185')]
# [('pname', 'language used'), ('oname', 'Piedmontese'), ('p', 'http://www.wikidata.org/prop/direct/P2936'), ('obj', 'http://www.wikidata.org/entity/Q15085')]
# [('pname', 'language used'), ('oname', 'Franco-Provençal'), ('p', 'http://www.wikidata.org/prop/direct/P2936'), ('obj', 'http://www.wikidata.org/entity/Q15087')]
# [('pname', 'language used'), ('oname', 'Venetian'), ('p', 'http://www.wikidata.org/prop/direct/P2936'), ('obj', 'http://www.wikidata.org/entity/Q32724')]
# [('pname', 'language used'), ('oname', 'Lombard'), ('p', 'http://www.wikidata.org/prop/direct/P2936'), ('obj', 'http://www.wikidata.org/entity/Q33754')]
# [('pname', 'language used'), ('oname', 'Gallurese'), ('p', 'http://www.wikidata.org/prop/direct/P2936'), ('obj', 'http://www.wikidata.org/entity/Q612220')]
# [('pname', 'language used'), ('oname', 'Walser German'), ('p', 'http://www.wikidata.org/prop/direct/P2936'), ('obj', 'http://www.wikidata.org/entity/Q680517')]
# [('pname', 'language used'), ('oname', 'Logudorese'), ('p', 'http://www.wikidata.org/prop/direct/P2936'), ('obj', 'http://www.wikidata.org/entity/Q777974')]
# [('pname', 'language used'), ('oname', 'International Sign'), ('p', 'http://www.wikidata.org/prop/direct/P2936'), ('obj', 'http://www.wikidata.org/entity/Q35754')]
# [('pname', 'language used'), ('oname', 'Ligurian'), ('p', 'http://www.wikidata.org/prop/direct/P2936'), ('obj', 'http://www.wikidata.org/entity/Q36106')]
# [('pname', 'language used'), ('oname', 'Ladin'), ('p', 'http://www.wikidata.org/prop/direct/P2936'), ('obj', 'http://www.wikidata.org/entity/Q36202')]
# [('pname', 'language used'), ('oname', 'Slavomolisano'), ('p', 'http://www.wikidata.org/prop/direct/P2936'), ('obj', 'http://www.wikidata.org/entity/Q36254')]
# [('pname', 'language used'), ('oname', 'Cimbrian'), ('p', 'http://www.wikidata.org/prop/direct/P2936'), ('obj', 'http://www.wikidata.org/entity/Q37053')]
# [('pname', 'language used'), ('oname', 'Corsican'), ('p', 'http://www.wikidata.org/prop/direct/P2936'), ('obj', 'http://www.wikidata.org/entity/Q33111')]
# [('pname', 'language used'), ('oname', 'Arbëresh'), ('p', 'http://www.wikidata.org/prop/direct/P2936'), ('obj', 'http://www.wikidata.org/entity/Q1075302')]
# [('pname', 'language used'), ('oname', 'Romagnol'), ('p', 'http://www.wikidata.org/prop/direct/P2936'), ('obj', 'http://www.wikidata.org/entity/Q1641543')]
# [('pname', 'language used'), ('oname', 'Campidanese'), ('p', 'http://www.wikidata.org/prop/direct/P2936'), ('obj', 'http://www.wikidata.org/entity/Q35348')]
# [('pname', 'language used'), ('oname', 'Italian Sign Language'), ('p', 'http://www.wikidata.org/prop/direct/P2936'), ('obj', 'http://www.wikidata.org/entity/Q375619')]
# [('pname', 'language used'), ('oname', 'Judæo-Italian languages'), ('p', 'http://www.wikidata.org/prop/direct/P2936'), ('obj', 'http://www.wikidata.org/entity/Q1145414')]
# [('pname', 'language used'), ('oname', 'Mòcheno'), ('p', 'http://www.wikidata.org/prop/direct/P2936'), ('obj', 'http://www.wikidata.org/entity/Q268130')]
# [('pname', 'language used'), ('oname', 'Sassarese'), ('p', 'http://www.wikidata.org/prop/direct/P2936'), ('obj', 'http://www.wikidata.org/entity/Q845441')]
# [('pname', 'legislative body'), ('oname', 'Italian Parliament'), ('p', 'http://www.wikidata.org/prop/direct/P194'), ('obj', 'http://www.wikidata.org/entity/Q1117578')]
# ...
# [('pname', 'member of'), ('oname', 'United Nations Industrial Development Organization'), ('p', 'http://www.wikidata.org/prop/direct/P463'), ('obj', 'http://www.wikidata.org/entity/Q386120')]
# [('pname', 'member of'), ('oname', 'Movement Coordination Centre Europe'), ('p', 'http://www.wikidata.org/prop/direct/P463'), ('obj', 'http://www.wikidata.org/entity/Q3866537')]
# [('pname', 'member of'), ('oname', 'Organisation for Economic Cooperation and Development'), ('p', 'http://www.wikidata.org/prop/direct/P463'), ('obj', 'http://www.wikidata.org/entity/Q41550')]
# [('pname', 'member of'), ('oname', 'International Atomic Energy Agency'), ('p', 'http://www.wikidata.org/prop/direct/P463'), ('obj', 'http://www.wikidata.org/entity/Q41984')]
# [('pname', 'member of'), ('oname', 'European Space Agency'), ('p', 'http://www.wikidata.org/prop/direct/P463'), ('obj', 'http://www.wikidata.org/entity/Q42262')]
# [('pname', 'member of'), ('oname', 'CERN'), ('p', 'http://www.wikidata.org/prop/direct/P463'), ('obj', 'http://www.wikidata.org/entity/Q42944')]
# [('pname', 'member of'), ('oname', 'Visa Waiver Program'), ('p', 'http://www.wikidata.org/prop/direct/P463'), ('obj', 'http://www.wikidata.org/entity/Q45177')]
# [('pname', 'member of'), ('oname', 'European Union'), ('p', 'http://www.wikidata.org/prop/direct/P463'), ('obj', 'http://www.wikidata.org/entity/Q458')]
# [('pname', 'member of'), ('oname', 'International Criminal Court'), ('p', 'http://www.wikidata.org/prop/direct/P463'), ('obj', 'http://www.wikidata.org/entity/Q47488')]
# [('pname', 'member of'), ('oname', 'Organisation for Joint Armament Cooperation'), ('p', 'http://www.wikidata.org/prop/direct/P463'), ('obj', 'http://www.wikidata.org/entity/Q521227')]
# [('pname', 'member of'), ('oname', 'International Labour Organization'), ('p', 'http://www.wikidata.org/prop/direct/P463'), ('obj', 'http://www.wikidata.org/entity/Q54129')]
# [('pname', 'member of'), ('oname', 'Group on Earth Observations'), ('p', 'http://www.wikidata.org/prop/direct/P463'), ('obj', 'http://www.wikidata.org/entity/Q5611262')]
# [('pname', 'member of'), ('oname', 'World Tourism Organization'), ('p', 'http://www.wikidata.org/prop/direct/P463'), ('obj', 'http://www.wikidata.org/entity/Q61923')]
# [('pname', 'member of'), ('oname', 'International Finance Corporation'), ('p', 'http://www.wikidata.org/prop/direct/P463'), ('obj', 'http://www.wikidata.org/entity/Q656801')]
# [('pname', 'member of'), ('oname', 'Eurocontrol'), ('p', 'http://www.wikidata.org/prop/direct/P463'), ('obj', 'http://www.wikidata.org/entity/Q663492')]
# [('pname', 'member of'), ('oname', 'International Fund for Agricultural Development'), ('p', 'http://www.wikidata.org/prop/direct/P463'), ('obj', 'http://www.wikidata.org/entity/Q689859')]
# [('pname', 'member of'), ('oname', 'NATO'), ('p', 'http://www.wikidata.org/prop/direct/P463'), ('obj', 'http://www.wikidata.org/entity/Q7184')]
# [('pname', 'member of'), ('oname', 'International Monetary Fund'), ('p', 'http://www.wikidata.org/prop/direct/P463'), ('obj', 'http://www.wikidata.org/entity/Q7804')]
# [('pname', 'member of'), ('oname', 'UNESCO'), ('p', 'http://www.wikidata.org/prop/direct/P463'), ('obj', 'http://www.wikidata.org/entity/Q7809')]
# [('pname', 'member of'), ('oname', 'World Health Organization'), ('p', 'http://www.wikidata.org/prop/direct/P463'), ('obj', 'http://www.wikidata.org/entity/Q7817')]
# [('pname', 'member of'), ('oname', 'World Trade Organization'), ('p', 'http://www.wikidata.org/prop/direct/P463'), ('obj', 'http://www.wikidata.org/entity/Q7825')]
# [('pname', 'member of'), ('oname', 'Australia Group'), ('p', 'http://www.wikidata.org/prop/direct/P463'), ('obj', 'http://www.wikidata.org/entity/Q782942')]
# [('pname', 'member of'), ('oname', 'Organization for Security and Co-operation in Europe'), ('p', 'http://www.wikidata.org/prop/direct/P463'), ('obj', 'http://www.wikidata.org/entity/Q81299')]
# [('pname', 'member of'), ('oname', 'Food and Agriculture Organization'), ('p', 'http://www.wikidata.org/prop/direct/P463'), ('obj', 'http://www.wikidata.org/entity/Q82151')]
# [('pname', 'member of'), ('oname', 'International Energy Agency'), ('p', 'http://www.wikidata.org/prop/direct/P463'), ('obj', 'http://www.wikidata.org/entity/Q826700')]
# [('pname', 'member of'), ('oname', 'International Development Association'), ('p', 'http://www.wikidata.org/prop/direct/P463'), ('obj', 'http://www.wikidata.org/entity/Q827525')]
# [('pname', 'member of'), ('oname', 'Organisation for the Prohibition of Chemical Weapons'), ('p', 'http://www.wikidata.org/prop/direct/P463'), ('obj', 'http://www.wikidata.org/entity/Q842490')]
# [('pname', 'member of'), ('oname', 'Interpol'), ('p', 'http://www.wikidata.org/prop/direct/P463'), ('obj', 'http://www.wikidata.org/entity/Q8475')]
# [('pname', 'member of'), ('oname', 'Council of Europe'), ('p', 'http://www.wikidata.org/prop/direct/P463'), ('obj', 'http://www.wikidata.org/entity/Q8908')]
# [('pname', 'member of'), ('oname', 'International Centre for Settlement of Investment Disputes'), ('p', 'http://www.wikidata.org/prop/direct/P463'), ('obj', 'http://www.wikidata.org/entity/Q899770')]
# [('pname', 'member of'), ('oname', 'United Nations High Commissioner for Refugees'), ('p', 'http://www.wikidata.org/prop/direct/P463'), ('obj', 'http://www.wikidata.org/entity/Q132551')]
# [('pname', 'member of'), ('oname', 'United Nations Truce Supervision Organization'), ('p', 'http://www.wikidata.org/prop/direct/P463'), ('obj', 'http://www.wikidata.org/entity/Q699036')]
# [('pname', 'member of'), ('oname', 'Interparliamentary Union'), ('p', 'http://www.wikidata.org/prop/direct/P463'), ('obj', 'http://www.wikidata.org/entity/Q176815')]
# [('pname', 'member of'), ('oname', 'United Nations Conference on Trade and Development'), ('p', 'http://www.wikidata.org/prop/direct/P463'), ('obj', 'http://www.wikidata.org/entity/Q182000')]
# [('pname', 'member of'), ('oname', 'International Red Cross and Red Crescent Movement'), ('p', 'http://www.wikidata.org/prop/direct/P463'), ('obj', 'http://www.wikidata.org/entity/Q7178')]
# [('pname', 'member of'), ('oname', 'European Economic Community'), ('p', 'http://www.wikidata.org/prop/direct/P463'), ('obj', 'http://www.wikidata.org/entity/Q52847')]
# [('pname', 'member of'), ('oname', 'World Customs Organization'), ('p', 'http://www.wikidata.org/prop/direct/P463'), ('obj', 'http://www.wikidata.org/entity/Q605326')]
# [('pname', 'member of'), ('oname', 'International Organization for Migration'), ('p', 'http://www.wikidata.org/prop/direct/P463'), ('obj', 'http://www.wikidata.org/entity/Q472311')]
# [('pname', 'member of'), ('oname', 'Bank for International Settlements'), ('p', 'http://www.wikidata.org/prop/direct/P463'), ('obj', 'http://www.wikidata.org/entity/Q309195')]
# [('pname', 'member of'), ('oname', 'Permanent Court of Arbitration'), ('p', 'http://www.wikidata.org/prop/direct/P463'), ('obj', 'http://www.wikidata.org/entity/Q1045198')]
# [('pname', 'member of'), ('oname', 'Euro-Atlantic Partnership Council'), ('p', 'http://www.wikidata.org/prop/direct/P463'), ('obj', 'http://www.wikidata.org/entity/Q1374456')]
# [('pname', 'member of'), ('oname', 'Group of Ten'), ('p', 'http://www.wikidata.org/prop/direct/P463'), ('obj', 'http://www.wikidata.org/entity/Q1411881')]
# [('pname', 'member of'), ('oname', 'International Mobile Satellite Organization'), ('p', 'http://www.wikidata.org/prop/direct/P463'), ('obj', 'http://www.wikidata.org/entity/Q1666759')]
# [('pname', 'member of'), ('oname', 'Procurement G6'), ('p', 'http://www.wikidata.org/prop/direct/P463'), ('obj', 'http://www.wikidata.org/entity/Q18816843')]
# [('pname', 'minimum temperature record'), ('p', 'http://www.wikidata.org/prop/direct/P7422'), ('obj', '-49.6')]
# [('pname', 'mobile country code'), ('p', 'http://www.wikidata.org/prop/direct/P2258'), ('obj', '222')]
# [('pname', 'motto text'), ('p', 'http://www.wikidata.org/prop/direct/P1451'), ('obj', 'Made in Italy')]
# [('pname', 'number of deaths'), ('p', 'http://www.wikidata.org/prop/direct/P1120'), ('obj', '633133')]
# [('pname', 'number of out-of-school children'), ('p', 'http://www.wikidata.org/prop/direct/P2573'), ('obj', '178653')]
# [('pname', 'office held by head of state'), ('oname', 'President of Italy'), ('p', 'http://www.wikidata.org/prop/direct/P1906'), ('obj', 'http://www.wikidata.org/entity/Q332711')]
# [('pname', 'office held by head of government'), ('oname', 'Prime Minister of Italy'), ('p', 'http://www.wikidata.org/prop/direct/P1313'), ('obj', 'http://www.wikidata.org/entity/Q796897')]
# [('pname', 'official language'), ('oname', 'Italian'), ('p', 'http://www.wikidata.org/prop/direct/P37'), ('obj', 'http://www.wikidata.org/entity/Q652')]
# [('pname', 'official website'), ('p', 'http://www.wikidata.org/prop/direct/P856'), ('obj', 'http://www.italia.it/')]
# [('pname', 'on focus list of Wikimedia project'), ('oname', 'WikiProject Zika Corpus'), ('p', 'http://www.wikidata.org/prop/direct/P5008'), ('obj', 'http://www.wikidata.org/entity/Q54439832')]
# [('pname', 'on focus list of Wikimedia project'), ('oname', 'Wikipedia:Vital articles'), ('p', 'http://www.wikidata.org/prop/direct/P5008'), ('obj', 'http://www.wikidata.org/entity/Q5460604')]
# [('pname', 'open data portal'), ('oname', 'Open Data Portal Italy'), ('p', 'http://www.wikidata.org/prop/direct/P8402'), ('obj', 'http://www.wikidata.org/entity/Q97013442')]
# [('pname', 'page banner'), ('p', 'http://www.wikidata.org/prop/direct/P948'), ('obj', 'http://commons.wikimedia.org/wiki/Special:FilePath/Italy%20banner%203%20Florence.jpg')]
# [('pname', 'part of'), ('oname', 'Europe'), ('p', 'http://www.wikidata.org/prop/direct/P361'), ('obj', 'http://www.wikidata.org/entity/Q46')]
# [('pname', 'patron saint'), ('oname', 'Francis of Assisi'), ('p', 'http://www.wikidata.org/prop/direct/P417'), ('obj', 'http://www.wikidata.org/entity/Q676555')]
# [('pname', 'patron saint'), ('oname', 'Catherine of Siena'), ('p', 'http://www.wikidata.org/prop/direct/P417'), ('obj', 'http://www.wikidata.org/entity/Q229190')]
# [('pname', 'permanent duplicated item'), ('p', 'http://www.wikidata.org/prop/direct/P2959'), ('obj', 'http://www.wikidata.org/entity/Q20820609')]
# [('pname', 'permanent duplicated item'), ('p', 'http://www.wikidata.org/prop/direct/P2959'), ('obj', 'http://www.wikidata.org/entity/Q30277415')]
# [('pname', 'population'), ('p', 'http://www.wikidata.org/prop/direct/P1082'), ('obj', '60317000')]
# [('pname', 'pronunciation audio'), ('p', 'http://www.wikidata.org/prop/direct/P443'), ('obj', 'http://commons.wikimedia.org/wiki/Special:FilePath/En-us-Italy.ogg')]
# [('pname', 'pronunciation audio'), ('p', 'http://www.wikidata.org/prop/direct/P443'), ('obj', 'http://commons.wikimedia.org/wiki/Special:FilePath/Fr-Italie.ogg')]
# [('pname', 'pronunciation audio'), ('p', 'http://www.wikidata.org/prop/direct/P443'), ('obj', 'http://commons.wikimedia.org/wiki/Special:FilePath/It-Italia.ogg')]
# [('pname', 'pronunciation audio'), ('p', 'http://www.wikidata.org/prop/direct/P443'), ('obj', 'http://commons.wikimedia.org/wiki/Special:FilePath/LL-Q7913%20%28ron%29-KlaudiuMihaila-Italia.wav')]
# [('pname', 'pronunciation audio'), ('p', 'http://www.wikidata.org/prop/direct/P443'), ('obj', 'http://commons.wikimedia.org/wiki/Special:FilePath/Lb-Italien.ogg')]
# [('pname', 'public holiday'), ('oname', "New Year's Day"), ('p', 'http://www.wikidata.org/prop/direct/P832'), ('obj', 'http://www.wikidata.org/entity/Q196627')]
# [('pname', 'public holiday'), ('oname', 'Christmas'), ('p', 'http://www.wikidata.org/prop/direct/P832'), ('obj', 'http://www.wikidata.org/entity/Q19809')]
# [('pname', 'public holiday'), ('oname', 'Easter Monday'), ('p', 'http://www.wikidata.org/prop/direct/P832'), ('obj', 'http://www.wikidata.org/entity/Q209663')]
# [('pname', 'public holiday'), ('oname', "International Workers' Day"), ('p', 'http://www.wikidata.org/prop/direct/P832'), ('obj', 'http://www.wikidata.org/entity/Q47499')]
# [('pname', 'public holiday'), ('oname', "All Saints' Day"), ('p', 'http://www.wikidata.org/prop/direct/P832'), ('obj', 'http://www.wikidata.org/entity/Q587')]
# [('pname', 'public holiday'), ('oname', 'Easter'), ('p', 'http://www.wikidata.org/prop/direct/P832'), ('obj', 'http://www.wikidata.org/entity/Q21196')]
# [('pname', 'public holiday'), ('oname', 'Epiphany'), ('p', 'http://www.wikidata.org/prop/direct/P832'), ('obj', 'http://www.wikidata.org/entity/Q132001')]
# [('pname', 'public holiday'), ('oname', "St. Stephen's Day"), ('p', 'http://www.wikidata.org/prop/direct/P832'), ('obj', 'http://www.wikidata.org/entity/Q1366863')]
# [('pname', 'public holiday'), ('oname', 'Feast of the Immaculate Conception'), ('p', 'http://www.wikidata.org/prop/direct/P832'), ('obj', 'http://www.wikidata.org/entity/Q3538509')]
# [('pname', 'public holiday'), ('oname', 'Ferragosto'), ('p', 'http://www.wikidata.org/prop/direct/P832'), ('obj', 'http://www.wikidata.org/entity/Q1262719')]
# [('pname', 'public holiday'), ('oname', 'Anniversary of the liberation of Italy'), ('p', 'http://www.wikidata.org/prop/direct/P832'), ('obj', 'http://www.wikidata.org/entity/Q2851732')]
# [('pname', 'public holiday'), ('oname', 'Festa della Repubblica'), ('p', 'http://www.wikidata.org/prop/direct/P832'), ('obj', 'http://www.wikidata.org/entity/Q802461')]
# [('pname', 'railway traffic side'), ('oname', 'left'), ('p', 'http://www.wikidata.org/prop/direct/P5658'), ('obj', 'http://www.wikidata.org/entity/Q13196750')]
# [('pname', 'replaces'), ('oname', 'Kingdom of Italy'), ('p', 'http://www.wikidata.org/prop/direct/P1365'), ('obj', 'http://www.wikidata.org/entity/Q172579')]
# [('pname', 'shape'), ('oname', 'boot'), ('p', 'http://www.wikidata.org/prop/direct/P1419'), ('obj', 'http://www.wikidata.org/entity/Q190868')]
# [('pname', 'shares border with'), ('oname', 'France'), ('p', 'http://www.wikidata.org/prop/direct/P47'), ('obj', 'http://www.wikidata.org/entity/Q142')]
# [('pname', 'shares border with'), ('oname', 'Slovenia'), ('p', 'http://www.wikidata.org/prop/direct/P47'), ('obj', 'http://www.wikidata.org/entity/Q215')]
# [('pname', 'shares border with'), ('oname', 'Malta'), ('p', 'http://www.wikidata.org/prop/direct/P47'), ('obj', 'http://www.wikidata.org/entity/Q233')]
# [('pname', 'shares border with'), ('oname', 'Vatican City'), ('p', 'http://www.wikidata.org/prop/direct/P47'), ('obj', 'http://www.wikidata.org/entity/Q237')]
# [('pname', 'shares border with'), ('oname', 'San Marino'), ('p', 'http://www.wikidata.org/prop/direct/P47'), ('obj', 'http://www.wikidata.org/entity/Q238')]
# [('pname', 'shares border with'), ('oname', 'Switzerland'), ('p', 'http://www.wikidata.org/prop/direct/P47'), ('obj', 'http://www.wikidata.org/entity/Q39')]
# [('pname', 'shares border with'), ('oname', 'Austria'), ('p', 'http://www.wikidata.org/prop/direct/P47'), ('obj', 'http://www.wikidata.org/entity/Q40')]
# [('pname', 'subreddit'), ('p', 'http://www.wikidata.org/prop/direct/P3984'), ('obj', 'it')]
# [('pname', 'subreddit'), ('p', 'http://www.wikidata.org/prop/direct/P3984'), ('obj', 'italy')]
# [('pname', 'top-level Internet domain'), ('oname', '.it'), ('p', 'http://www.wikidata.org/prop/direct/P78'), ('obj', 'http://www.wikidata.org/entity/Q39155')]
# [('pname', "topic's main Wikimedia portal"), ('oname', 'Portal:Italy'), ('p', 'http://www.wikidata.org/prop/direct/P1151'), ('obj', 'http://www.wikidata.org/entity/Q10631821')]
# [('pname', "topic's main category"), ('oname', 'Category:Italy'), ('p', 'http://www.wikidata.org/prop/direct/P910'), ('obj', 'http://www.wikidata.org/entity/Q1410903')]
# [('pname', 'total fertility rate'), ('p', 'http://www.wikidata.org/prop/direct/P4841'), ('obj', '1.39')]
# [('pname', 'unemployment rate'), ('p', 'http://www.wikidata.org/prop/direct/P1198'), ('obj', '12')]
# [('pname', 'voltage'), ('p', 'http://www.wikidata.org/prop/direct/P2436'), ('obj', '230')]
# [('pname', 'Ávvir topic ID'), ('p', 'http://www.wikidata.org/prop/direct/P9318'), ('obj', 'italia')]
# [('pname', 'Österreichisches Musiklexikon Online ID'), ('p', 'http://www.wikidata.org/prop/direct/P8432'), ('obj', 'I/Italien')]
# 495

# %% [markdown]
# #### Comment
# We have discovered:
#
# | IRI           | Description   | Role      |
# | -----------   | -----------   |-----------|
# | `wdt:P463`   | member of   | predicate |
# | `wd:Q458`     | European Union   | node |
#
# European Union = E.U.

# %%
#Let's try to find the relations between a politiciaan and a country using as an example the country "Italy" 
queryString = """
SELECT DISTINCT ?pname ?p
WHERE { 

# ?pol wdt:P106/wdt:P279* wd:Q82955 ;
     # ?p wd:Q38 .

# ?p <http://schema.org/name> ?pname .
# ?pol <http://schema.org/name> ?sname .
}
"""

print("Results")
run_query(queryString)
# Out:
# Results
# The operation failed EndPointInternalError: endpoint returned code 500 and response.
#
# Response:
# b'Virtuoso 42000 Error TN...: Exceeded 1000000000 bytes in transitive temp memory.  use t_distinct, t_max or more T_MAX_memory options to limit the search or increase the pool\n\nSPARQL query:\ndefine sql:big-data-const 0\n#output-format:application/sparql-results+json\n\n##-e1cf476009-##\nPREFIX wd: <http://www.wikidata.org/entity/> \nPREFIX wdt: <http://www.wikidata.org/prop/direct/> \nPREFIX sc: <http://schema.org/>\n\n\nSELECT DISTINCT ?pname\nWHERE { \n\n?pol wdt:P106/wdt:P279* wd:Q82955 ;\n     ?p wd:Q38 .\n\n?p <http://schema.org/name> ?pname .\n?pol <http://schema.org/name> ?sname .\n}\n'

# %% [markdown]
# #### Comment
# It seesm that with the asterisk the search is too onerous, so let's try something else

# %%
#Let's try to restrict the usage of "subclass of"property only between 0 and 2 times
queryString = """
SELECT DISTINCT ?pname ?p
WHERE { 

# ?pol wdt:P106/wdt:P279{0,2} wd:Q82955 ;
     # ?p wd:Q38 .

# ?p <http://schema.org/name> ?pname .
# ?pol <http://schema.org/name> ?sname .
}
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('pname', 'country for sport'), ('p', 'http://www.wikidata.org/prop/direct/P1532')]
# [('pname', 'headquarters location'), ('p', 'http://www.wikidata.org/prop/direct/P159')]
# [('pname', 'place of birth'), ('p', 'http://www.wikidata.org/prop/direct/P19')]
# [('pname', 'ethnic group'), ('p', 'http://www.wikidata.org/prop/direct/P172')]
# [('pname', 'country of citizenship'), ('p', 'http://www.wikidata.org/prop/direct/P27')]
# [('pname', 'place of death'), ('p', 'http://www.wikidata.org/prop/direct/P20')]
# [('pname', 'place of detention'), ('p', 'http://www.wikidata.org/prop/direct/P2632')]
# [('pname', 'residence'), ('p', 'http://www.wikidata.org/prop/direct/P551')]
# [('pname', 'ancestral home'), ('p', 'http://www.wikidata.org/prop/direct/P66')]
# [('pname', 'work location'), ('p', 'http://www.wikidata.org/prop/direct/P937')]
# [('pname', 'allegiance'), ('p', 'http://www.wikidata.org/prop/direct/P945')]
# [('pname', 'domain of saint or deity'), ('p', 'http://www.wikidata.org/prop/direct/P2925')]
# 12

# %% [markdown]
# #### Comment
# These could be potential properties that connects a politician with it's working country

# %%
#Let's try to print the distinct politician properies
queryString = """
SELECT DISTINCT ?pname ?p
WHERE { 

# ?pol wdt:P106/wdt:P279{0,2} wd:Q82955 ;
     # ?p ?obj .

# ?p <http://schema.org/name> ?pname .
# ?pol <http://schema.org/name> ?sname .
OPTIONAL { ?obj <http://schema.org/name> ?oname . } .

}
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('pname', 'stepparent'), ('p', 'http://www.wikidata.org/prop/direct/P3448')]
# [('pname', 'Loop ID'), ('p', 'http://www.wikidata.org/prop/direct/P2798')]
# [('pname', 'Nationale Thesaurus voor Auteurs ID'), ('p', 'http://www.wikidata.org/prop/direct/P1006')]
# [('pname', 'field of work'), ('p', 'http://www.wikidata.org/prop/direct/P101')]
# [('pname', 'member of political party'), ('p', 'http://www.wikidata.org/prop/direct/P102')]
# [('pname', 'native language'), ('p', 'http://www.wikidata.org/prop/direct/P103')]
# [('pname', 'relative'), ('p', 'http://www.wikidata.org/prop/direct/P1038')]
# [('pname', 'ResearcherID'), ('p', 'http://www.wikidata.org/prop/direct/P1053')]
# [('pname', 'occupation'), ('p', 'http://www.wikidata.org/prop/direct/P106')]
# [('pname', 'employer'), ('p', 'http://www.wikidata.org/prop/direct/P108')]
# [('pname', 'from narrative universe'), ('p', 'http://www.wikidata.org/prop/direct/P1080')]
# [('pname', 'signature'), ('p', 'http://www.wikidata.org/prop/direct/P109')]
# [('pname', 'Rodovid ID'), ('p', 'http://www.wikidata.org/prop/direct/P1185')]
# [('pname', 'MEP directory ID'), ('p', 'http://www.wikidata.org/prop/direct/P1186')]
# [('pname', 'Dharma Drum Institute of Liberal Arts person ID'), ('p', 'http://www.wikidata.org/prop/direct/P1187')]
# [('pname', 'place of burial'), ('p', 'http://www.wikidata.org/prop/direct/P119')]
# [('pname', 'manner of death'), ('p', 'http://www.wikidata.org/prop/direct/P1196')]
# [('pname', 'NUKAT ID'), ('p', 'http://www.wikidata.org/prop/direct/P1207')]
# [('pname', 'Munzinger person ID'), ('p', 'http://www.wikidata.org/prop/direct/P1284')]
# [('pname', 'Gran Enciclopèdia Catalana ID'), ('p', 'http://www.wikidata.org/prop/direct/P1296')]
# [('pname', 'depicted by'), ('p', 'http://www.wikidata.org/prop/direct/P1299')]
# [('pname', 'NLA Trove ID'), ('p', 'http://www.wikidata.org/prop/direct/P1315')]
# [('pname', 'floruit'), ('p', 'http://www.wikidata.org/prop/direct/P1317')]
# [('pname', 'eye color'), ('p', 'http://www.wikidata.org/prop/direct/P1340')]
# [('pname', 'described by source'), ('p', 'http://www.wikidata.org/prop/direct/P1343')]
# [('pname', 'replaces'), ('p', 'http://www.wikidata.org/prop/direct/P1365')]
# [('pname', 'replaced by'), ('p', 'http://www.wikidata.org/prop/direct/P1366')]
# [('pname', 'religion'), ('p', 'http://www.wikidata.org/prop/direct/P140')]
# [('pname', 'nominated for'), ('p', 'http://www.wikidata.org/prop/direct/P1411')]
# [('pname', 'languages spoken, written or signed'), ('p', 'http://www.wikidata.org/prop/direct/P1412')]
# [('pname', 'Encyclopædia Britannica Online ID'), ('p', 'http://www.wikidata.org/prop/direct/P1417')]
# [('pname', 'Sandrart.net person ID'), ('p', 'http://www.wikidata.org/prop/direct/P1422')]
# [('pname', 'present in work'), ('p', 'http://www.wikidata.org/prop/direct/P1441')]
# [('pname', 'image of grave'), ('p', 'http://www.wikidata.org/prop/direct/P1442')]
# [('pname', 'birth name'), ('p', 'http://www.wikidata.org/prop/direct/P1477')]
# [('pname', 'monogram'), ('p', 'http://www.wikidata.org/prop/direct/P1543')]
# [('pname', 'name in native language'), ('p', 'http://www.wikidata.org/prop/direct/P1559')]
# [('pname', 'killed by'), ('p', 'http://www.wikidata.org/prop/direct/P157')]
# [('pname', 'seal image'), ('p', 'http://www.wikidata.org/prop/direct/P158')]
# [('pname', 'award received'), ('p', 'http://www.wikidata.org/prop/direct/P166')]
# [('pname', 'NLP ID (unique)'), ('p', 'http://www.wikidata.org/prop/direct/P1695')]
# [('pname', 'creator'), ('p', 'http://www.wikidata.org/prop/direct/P170')]
# [('pname', 'Sächsische Biografie (GND) ID'), ('p', 'http://www.wikidata.org/prop/direct/P1710')]
# [('pname', 'British Museum person or institution ID'), ('p', 'http://www.wikidata.org/prop/direct/P1711')]
# [('pname', 'ethnic group'), ('p', 'http://www.wikidata.org/prop/direct/P172')]
# [('pname', 'performer'), ('p', 'http://www.wikidata.org/prop/direct/P175')]
# [('pname', 'courtesy name'), ('p', 'http://www.wikidata.org/prop/direct/P1782')]
# [('pname', 'temple name'), ('p', 'http://www.wikidata.org/prop/direct/P1785')]
# [('pname', 'posthumous name'), ('p', 'http://www.wikidata.org/prop/direct/P1786')]
# [('pname', 'image'), ('p', 'http://www.wikidata.org/prop/direct/P18')]
# [('pname', 'EMLO person ID'), ('p', 'http://www.wikidata.org/prop/direct/P1802')]
# [('pname', 'name in kana'), ('p', 'http://www.wikidata.org/prop/direct/P1814')]
# [('pname', 'genealogics.org person ID'), ('p', 'http://www.wikidata.org/prop/direct/P1819')]
# [('pname', 'CERL Thesaurus ID'), ('p', 'http://www.wikidata.org/prop/direct/P1871')]
# [('pname', 'hair color'), ('p', 'http://www.wikidata.org/prop/direct/P1884')]
# [('pname', 'different from'), ('p', 'http://www.wikidata.org/prop/direct/P1889')]
# [('pname', 'place of birth'), ('p', 'http://www.wikidata.org/prop/direct/P19')]
# [('pname', 'McCune-Reischauer romanization'), ('p', 'http://www.wikidata.org/prop/direct/P1942')]
# [('pname', 'second family name in Spanish name'), ('p', 'http://www.wikidata.org/prop/direct/P1950')]
# [('pname', 'number of children'), ('p', 'http://www.wikidata.org/prop/direct/P1971')]
# [('pname', 'PolSys ID'), ('p', 'http://www.wikidata.org/prop/direct/P1980')]
# [('pname', 'place of death'), ('p', 'http://www.wikidata.org/prop/direct/P20')]
# [('pname', 'Revised Romanization'), ('p', 'http://www.wikidata.org/prop/direct/P2001')]
# [('pname', 'Twitter username'), ('p', 'http://www.wikidata.org/prop/direct/P2002')]
# [('pname', 'Instagram username'), ('p', 'http://www.wikidata.org/prop/direct/P2003')]
# [('pname', 'Facebook ID'), ('p', 'http://www.wikidata.org/prop/direct/P2013')]
# [('pname', 'Crunchbase person ID'), ('p', 'http://www.wikidata.org/prop/direct/P2087')]
# [('pname', 'sex or gender'), ('p', 'http://www.wikidata.org/prop/direct/P21')]
# [('pname', 'ISNI'), ('p', 'http://www.wikidata.org/prop/direct/P213')]
# [('pname', 'VIAF ID'), ('p', 'http://www.wikidata.org/prop/direct/P214')]
# [('pname', 'FAST ID'), ('p', 'http://www.wikidata.org/prop/direct/P2163')]
# [('pname', 'C-SPAN person ID'), ('p', 'http://www.wikidata.org/prop/direct/P2190')]
# [('pname', 'father'), ('p', 'http://www.wikidata.org/prop/direct/P22')]
# [('pname', 'GND ID'), ('p', 'http://www.wikidata.org/prop/direct/P227')]
# [('pname', 'time period'), ('p', 'http://www.wikidata.org/prop/direct/P2348')]
# [('pname', 'Roman nomen gentilicium'), ('p', 'http://www.wikidata.org/prop/direct/P2359')]
# [('pname', 'Academic Tree ID'), ('p', 'http://www.wikidata.org/prop/direct/P2381')]
# [('pname', 'YouTube channel ID'), ('p', 'http://www.wikidata.org/prop/direct/P2397')]
# [('pname', 'Library of Congress authority ID'), ('p', 'http://www.wikidata.org/prop/direct/P244')]
# [('pname', 'mother'), ('p', 'http://www.wikidata.org/prop/direct/P25')]
# [('pname', 'spouse'), ('p', 'http://www.wikidata.org/prop/direct/P26')]
# [('pname', 'Geni.com profile ID'), ('p', 'http://www.wikidata.org/prop/direct/P2600')]
# [('pname', 'Google Knowledge Graph ID'), ('p', 'http://www.wikidata.org/prop/direct/P2671')]
# [('pname', 'Bibliothèque nationale de France ID'), ('p', 'http://www.wikidata.org/prop/direct/P268')]
# [('pname', 'IdRef ID'), ('p', 'http://www.wikidata.org/prop/direct/P269')]
# [('pname', 'country of citizenship'), ('p', 'http://www.wikidata.org/prop/direct/P27')]
# [('pname', 'Great Russian Encyclopedia Online ID'), ('p', 'http://www.wikidata.org/prop/direct/P2924')]
# [('pname', 'WikiTree person ID'), ('p', 'http://www.wikidata.org/prop/direct/P2949')]
# [('pname', 'Nomisma ID'), ('p', 'http://www.wikidata.org/prop/direct/P2950')]
# [('pname', 'Goodreads author ID'), ('p', 'http://www.wikidata.org/prop/direct/P2963')]
# [('pname', 'instance of'), ('p', 'http://www.wikidata.org/prop/direct/P31')]
# [('pname', 'NE.se ID'), ('p', 'http://www.wikidata.org/prop/direct/P3222')]
# [('pname', 'Flickr user ID'), ('p', 'http://www.wikidata.org/prop/direct/P3267')]
# [('pname', 'significant person'), ('p', 'http://www.wikidata.org/prop/direct/P3342')]
# [('pname', 'sibling'), ('p', 'http://www.wikidata.org/prop/direct/P3373')]
# [('pname', 'SNAC ARK ID'), ('p', 'http://www.wikidata.org/prop/direct/P3430')]
# [('pname', 'IMDb ID'), ('p', 'http://www.wikidata.org/prop/direct/P345')]
# [('pname', 'National Diet Library ID'), ('p', 'http://www.wikidata.org/prop/direct/P349')]
# [('pname', 'Zhihu topic ID'), ('p', 'http://www.wikidata.org/prop/direct/P3553')]
# [('pname', 'candidacy in election'), ('p', 'http://www.wikidata.org/prop/direct/P3602')]
# [('pname', 'Babelio author ID'), ('p', 'http://www.wikidata.org/prop/direct/P3630')]
# [('pname', 'Commons category'), ('p', 'http://www.wikidata.org/prop/direct/P373')]
# [('pname', 'Publons author ID'), ('p', 'http://www.wikidata.org/prop/direct/P3829')]
# [('pname', 'position held'), ('p', 'http://www.wikidata.org/prop/direct/P39')]
# [('pname', 'child'), ('p', 'http://www.wikidata.org/prop/direct/P40')]
# [('pname', 'Libraries Australia ID'), ('p', 'http://www.wikidata.org/prop/direct/P409')]
# [('pname', 'military rank'), ('p', 'http://www.wikidata.org/prop/direct/P410')]
# [('pname', 'canonization status'), ('p', 'http://www.wikidata.org/prop/direct/P411')]
# [('pname', "Who's Who in France biography ID"), ('p', 'http://www.wikidata.org/prop/direct/P4124')]
# [('pname', 'WeRelate person ID'), ('p', 'http://www.wikidata.org/prop/direct/P4159')]
# [('pname', 'The Times of India topic ID'), ('p', 'http://www.wikidata.org/prop/direct/P4204')]
# [('pname', 'Nominis saint ID'), ('p', 'http://www.wikidata.org/prop/direct/P4286')]
# [('pname', 'MusicBrainz artist ID'), ('p', 'http://www.wikidata.org/prop/direct/P434')]
# [('pname', 'Store norske leksikon ID'), ('p', 'http://www.wikidata.org/prop/direct/P4342')]
# [('pname', 'pronunciation audio'), ('p', 'http://www.wikidata.org/prop/direct/P443')]
# [('pname', 'LesBiographies.com ID'), ('p', 'http://www.wikidata.org/prop/direct/P4434')]
# [('pname', 'Spanish Biographical Dictionary ID'), ('p', 'http://www.wikidata.org/prop/direct/P4459')]
# [('pname', 'unmarried partner'), ('p', 'http://www.wikidata.org/prop/direct/P451')]
# [('pname', 'first appearance'), ('p', 'http://www.wikidata.org/prop/direct/P4584')]
# [('pname', 'said to be the same as'), ('p', 'http://www.wikidata.org/prop/direct/P460')]
# [('pname', 'member of'), ('p', 'http://www.wikidata.org/prop/direct/P463')]
# [('pname', 'The Peerage person ID'), ('p', 'http://www.wikidata.org/prop/direct/P4638')]
# [('pname', 'Amazon author ID'), ('p', 'http://www.wikidata.org/prop/direct/P4862')]
# [('pname', 'ORCID iD'), ('p', 'http://www.wikidata.org/prop/direct/P496')]
# [('pname', 'derivative work'), ('p', 'http://www.wikidata.org/prop/direct/P4969')]
# [('pname', 'CBDB ID'), ('p', 'http://www.wikidata.org/prop/direct/P497')]
# [('pname', 'Orthodox Encyclopedia ID'), ('p', 'http://www.wikidata.org/prop/direct/P5002')]
# [('pname', 'on focus list of Wikimedia project'), ('p', 'http://www.wikidata.org/prop/direct/P5008')]
# [('pname', 'Brockhaus Enzyklopädie online ID'), ('p', 'http://www.wikidata.org/prop/direct/P5019')]
# [('pname', 'gens'), ('p', 'http://www.wikidata.org/prop/direct/P5025')]
# [('pname', 'National Library of Korea ID'), ('p', 'http://www.wikidata.org/prop/direct/P5034')]
# [('pname', 'cause of death'), ('p', 'http://www.wikidata.org/prop/direct/P509')]
# [('pname', 'Daum Encyclopedia ID'), ('p', 'http://www.wikidata.org/prop/direct/P5184')]
# [('pname', 'family'), ('p', 'http://www.wikidata.org/prop/direct/P53')]
# [('pname', 'Google News topics ID'), ('p', 'http://www.wikidata.org/prop/direct/P5337')]
# [('pname', 'Find A Grave memorial ID'), ('p', 'http://www.wikidata.org/prop/direct/P535')]
# [('pname', 'RISM ID'), ('p', 'http://www.wikidata.org/prop/direct/P5504')]
# [('pname', 'residence'), ('p', 'http://www.wikidata.org/prop/direct/P551')]
# [('pname', 'Libris-URI'), ('p', 'http://www.wikidata.org/prop/direct/P5587')]
# [('pname', 'date of birth'), ('p', 'http://www.wikidata.org/prop/direct/P569')]
# [('pname', 'date of death'), ('p', 'http://www.wikidata.org/prop/direct/P570')]
# [('pname', 'inception'), ('p', 'http://www.wikidata.org/prop/direct/P571')]
# [('pname', 'Academia.edu profile URL'), ('p', 'http://www.wikidata.org/prop/direct/P5715')]
# [('pname', 'publication date'), ('p', 'http://www.wikidata.org/prop/direct/P577')]
# [('pname', 'narrative role'), ('p', 'http://www.wikidata.org/prop/direct/P5800')]
# [('pname', 'Comic Vine ID'), ('p', 'http://www.wikidata.org/prop/direct/P5905')]
# [('pname', 'HKCAN ID'), ('p', 'http://www.wikidata.org/prop/direct/P5909')]
# [('pname', 'conflict'), ('p', 'http://www.wikidata.org/prop/direct/P607')]
# [('pname', 'Santiebeati ID'), ('p', 'http://www.wikidata.org/prop/direct/P6126')]
# [('pname', 'Disney A to Z ID'), ('p', 'http://www.wikidata.org/prop/direct/P6181')]
# [('pname', "Treccani's Dizionario di Storia ID"), ('p', 'http://www.wikidata.org/prop/direct/P6404')]
# [('pname', 'Freebase ID'), ('p', 'http://www.wikidata.org/prop/direct/P646')]
# [('pname', 'Open Library ID'), ('p', 'http://www.wikidata.org/prop/direct/P648')]
# [('pname', 'LinkedIn personal profile ID'), ('p', 'http://www.wikidata.org/prop/direct/P6634')]
# [('pname', 'Japan Search name ID'), ('p', 'http://www.wikidata.org/prop/direct/P6698')]
# [('pname', 'Academia Sinica authority ID'), ('p', 'http://www.wikidata.org/prop/direct/P6705')]
# [('pname', 'De Agostini ID'), ('p', 'http://www.wikidata.org/prop/direct/P6706')]
# [('pname', 'FemBio ID'), ('p', 'http://www.wikidata.org/prop/direct/P6722')]
# [('pname', 'has written for'), ('p', 'http://www.wikidata.org/prop/direct/P6872')]
# [('pname', 'educated at'), ('p', 'http://www.wikidata.org/prop/direct/P69')]
# [('pname', 'era name'), ('p', 'http://www.wikidata.org/prop/direct/P6902')]
# [('pname', 'NKCR AUT ID'), ('p', 'http://www.wikidata.org/prop/direct/P691')]
# [('pname', 'enemy of'), ('p', 'http://www.wikidata.org/prop/direct/P7047')]
# [('pname', 'PLWABN ID'), ('p', 'http://www.wikidata.org/prop/direct/P7293')]
# [('pname', 'TDV İslam Ansiklopedisi ID'), ('p', 'http://www.wikidata.org/prop/direct/P7314')]
# [('pname', 'family name'), ('p', 'http://www.wikidata.org/prop/direct/P734')]
# [('pname', 'given name'), ('p', 'http://www.wikidata.org/prop/direct/P735')]
# [('pname', 'contributor to the creative work or subject'), ('p', 'http://www.wikidata.org/prop/direct/P767')]
# [('pname', 'Vie publique person ID'), ('p', 'http://www.wikidata.org/prop/direct/P7676')]
# [('pname', 'copyright status as a creator'), ('p', 'http://www.wikidata.org/prop/direct/P7763')]
# [('pname', 'WorldCat Identities ID'), ('p', 'http://www.wikidata.org/prop/direct/P7859')]
# [('pname', 'Deutsche Biographie (GND) ID'), ('p', 'http://www.wikidata.org/prop/direct/P7902')]
# [('pname', 'BioLexSOE ID'), ('p', 'http://www.wikidata.org/prop/direct/P7928')]
# [('pname', 'Roglo person ID'), ('p', 'http://www.wikidata.org/prop/direct/P7929')]
# [('pname', 'significant event'), ('p', 'http://www.wikidata.org/prop/direct/P793')]
# [('pname', 'notable work'), ('p', 'http://www.wikidata.org/prop/direct/P800')]
# [('pname', 'professorship'), ('p', 'http://www.wikidata.org/prop/direct/P803')]
# [('pname', 'Vatican Library VcBA ID'), ('p', 'http://www.wikidata.org/prop/direct/P8034')]
# [('pname', 'WBIS ID'), ('p', 'http://www.wikidata.org/prop/direct/P8081')]
# [('pname', 'FactGrid item ID'), ('p', 'http://www.wikidata.org/prop/direct/P8168')]
# [('pname', 'Sejm-Wielki.pl profile ID'), ('p', 'http://www.wikidata.org/prop/direct/P8172')]
# [('pname', 'media franchise'), ('p', 'http://www.wikidata.org/prop/direct/P8345')]
# [('pname', 'feast day'), ('p', 'http://www.wikidata.org/prop/direct/P841')]
# [('pname', 'Personendatenbank Germania Sacra ID'), ('p', 'http://www.wikidata.org/prop/direct/P8440')]
# [('pname', 'official website'), ('p', 'http://www.wikidata.org/prop/direct/P856')]
# [('pname', 'social media followers'), ('p', 'http://www.wikidata.org/prop/direct/P8687')]
# [('pname', 'Namuwiki ID'), ('p', 'http://www.wikidata.org/prop/direct/P8885')]
# [('pname', 'World History Encyclopedia ID'), ('p', 'http://www.wikidata.org/prop/direct/P9000')]
# [('pname', 'BHCL UUID'), ('p', 'http://www.wikidata.org/prop/direct/P9037')]
# [('pname', 'SELIBR ID'), ('p', 'http://www.wikidata.org/prop/direct/P906')]
# [('pname', 'character type'), ('p', 'http://www.wikidata.org/prop/direct/P9071')]
# [('pname', "topic's main category"), ('p', 'http://www.wikidata.org/prop/direct/P910')]
# [('pname', 'work location'), ('p', 'http://www.wikidata.org/prop/direct/P937')]
# [('pname', 'coat of arms image'), ('p', 'http://www.wikidata.org/prop/direct/P94')]
# [('pname', 'inspired by'), ('p', 'http://www.wikidata.org/prop/direct/P941')]
# [('pname', 'ctext data entity ID'), ('p', 'http://www.wikidata.org/prop/direct/P9613')]
# [('pname', 'noble title'), ('p', 'http://www.wikidata.org/prop/direct/P97')]
# [('pname', 'described at URL'), ('p', 'http://www.wikidata.org/prop/direct/P973')]
# [('pname', 'Auñamendi ID'), ('p', 'http://www.wikidata.org/prop/direct/P3218')]
# [('pname', 'Medium username'), ('p', 'http://www.wikidata.org/prop/direct/P3899')]
# [('pname', 'last words'), ('p', 'http://www.wikidata.org/prop/direct/P3909')]
# [('pname', 'HATVP person ID'), ('p', 'http://www.wikidata.org/prop/direct/P4703')]
# [('pname', 'honorific prefix'), ('p', 'http://www.wikidata.org/prop/direct/P511')]
# [('pname', 'Kaiserhof ID'), ('p', 'http://www.wikidata.org/prop/direct/P1818')]
# [('pname', 'ResearchGate profile ID'), ('p', 'http://www.wikidata.org/prop/direct/P2038')]
# [('pname', 'contributed to creative work'), ('p', 'http://www.wikidata.org/prop/direct/P3919')]
# [('pname', 'Y-DNA Haplogroup'), ('p', 'http://www.wikidata.org/prop/direct/P4426')]
# [('pname', 'Muck Rack journalist ID'), ('p', 'http://www.wikidata.org/prop/direct/P6005')]
# [('pname', 'Storting person ID'), ('p', 'http://www.wikidata.org/prop/direct/P3072')]
# [('pname', 'art-name'), ('p', 'http://www.wikidata.org/prop/direct/P1787')]
# [('pname', 'INDUCKS character ID'), ('p', 'http://www.wikidata.org/prop/direct/P4479')]
# [('pname', 'SlideShare username'), ('p', 'http://www.wikidata.org/prop/direct/P4016')]
# [('pname', 'Marvel character ID'), ('p', 'http://www.wikidata.org/prop/direct/P5621')]
# [('pname', 'Portuguese National Library ID'), ('p', 'http://www.wikidata.org/prop/direct/P1005')]
# [('pname', 'Art & Architecture Thesaurus ID'), ('p', 'http://www.wikidata.org/prop/direct/P1014')]
# [('pname', 'NORAF ID'), ('p', 'http://www.wikidata.org/prop/direct/P1015')]
# [('pname', 'Vatican Library ID (former scheme)'), ('p', 'http://www.wikidata.org/prop/direct/P1017')]
# [('pname', 'medical condition'), ('p', 'http://www.wikidata.org/prop/direct/P1050')]
# [('pname', 'student of'), ('p', 'http://www.wikidata.org/prop/direct/P1066')]
# [('pname', 'Iconclass notation'), ('p', 'http://www.wikidata.org/prop/direct/P1256')]
# [('pname', 'NNDB people ID'), ('p', 'http://www.wikidata.org/prop/direct/P1263')]
# [('pname', 'CANTIC ID'), ('p', 'http://www.wikidata.org/prop/direct/P1273')]
# [('pname', 'LNB ID'), ('p', 'http://www.wikidata.org/prop/direct/P1368')]
# [('pname', 'NSK ID'), ('p', 'http://www.wikidata.org/prop/direct/P1375')]
# [('pname', 'Oxford Dictionary of National Biography ID'), ('p', 'http://www.wikidata.org/prop/direct/P1415')]
# [('pname', 'OpenPlaques subject ID'), ('p', 'http://www.wikidata.org/prop/direct/P1430')]
# [('pname', 'University of Barcelona authority ID'), ('p', 'http://www.wikidata.org/prop/direct/P1580')]
# [('pname', 'Canadiana Authorities ID (former scheme)'), ('p', 'http://www.wikidata.org/prop/direct/P1670')]
# [('pname', 'Great Aragonese Encyclopedia ID'), ('p', 'http://www.wikidata.org/prop/direct/P1807')]
# [('pname', 'National Portrait Gallery (London) person ID'), ('p', 'http://www.wikidata.org/prop/direct/P1816')]
# [('pname', 'owner of'), ('p', 'http://www.wikidata.org/prop/direct/P1830')]
# [('pname', 'CCAB ID'), ('p', 'http://www.wikidata.org/prop/direct/P1890')]
# [('pname', 'Discogs artist ID'), ('p', 'http://www.wikidata.org/prop/direct/P1953')]
# [('pname', 'Biographical Dictionary of Italian People ID'), ('p', 'http://www.wikidata.org/prop/direct/P1986')]
# [('pname', 'height'), ('p', 'http://www.wikidata.org/prop/direct/P2048')]
# [('pname', 'mass'), ('p', 'http://www.wikidata.org/prop/direct/P2067')]
# [('pname', 'PolitiFact people and groups ID'), ('p', 'http://www.wikidata.org/prop/direct/P2267')]
# [('pname', 'Roman cognomen'), ('p', 'http://www.wikidata.org/prop/direct/P2365')]
# [('pname', 'Union List of Artist Names ID'), ('p', 'http://www.wikidata.org/prop/direct/P245')]
# [('pname', 'superhuman feature or ability'), ('p', 'http://www.wikidata.org/prop/direct/P2563')]
# [('pname', 'ČSFD person ID'), ('p', 'http://www.wikidata.org/prop/direct/P2605')]
# [('pname', 'CiNii author ID (books)'), ('p', 'http://www.wikidata.org/prop/direct/P271')]
# [('pname', 'BVMC person ID'), ('p', 'http://www.wikidata.org/prop/direct/P2799')]
# [('pname', 'National Library of Wales Authority ID'), ('p', 'http://www.wikidata.org/prop/direct/P2966')]
# [('pname', 'LBT person ID'), ('p', 'http://www.wikidata.org/prop/direct/P2977')]
# [('pname', 'UK National Archives ID'), ('p', 'http://www.wikidata.org/prop/direct/P3029')]
# [('pname', 'Kindred Britain ID'), ('p', 'http://www.wikidata.org/prop/direct/P3051')]
# [('pname', 'RERO ID'), ('p', 'http://www.wikidata.org/prop/direct/P3065')]
# [('pname', 'Guardian topic ID'), ('p', 'http://www.wikidata.org/prop/direct/P3106')]
# [('pname', 'Runeberg author ID'), ('p', 'http://www.wikidata.org/prop/direct/P3154')]
# [('pname', 'Dictionary of Swedish National Biography ID'), ('p', 'http://www.wikidata.org/prop/direct/P3217')]
# [('pname', 'Encyclopædia Universalis ID'), ('p', 'http://www.wikidata.org/prop/direct/P3219')]
# [('pname', 'Catholic Encyclopedia ID'), ('p', 'http://www.wikidata.org/prop/direct/P3241')]
# [('pname', 'BAnQ author ID'), ('p', 'http://www.wikidata.org/prop/direct/P3280')]
# [('pname', 'National Library of Greece ID'), ('p', 'http://www.wikidata.org/prop/direct/P3348')]
# [('pname', 'LittleSis people ID'), ('p', 'http://www.wikidata.org/prop/direct/P3388')]
# [('pname', 'Quora topic ID'), ('p', 'http://www.wikidata.org/prop/direct/P3417')]
# [('pname', 'Electronic Enlightenment ID'), ('p', 'http://www.wikidata.org/prop/direct/P3429')]
# [('pname', 'Te Papa agent ID'), ('p', 'http://www.wikidata.org/prop/direct/P3544')]
# [('pname', 'part of'), ('p', 'http://www.wikidata.org/prop/direct/P361')]
# [('pname', 'social classification'), ('p', 'http://www.wikidata.org/prop/direct/P3716')]
# [('pname', 'openMLOL author ID'), ('p', 'http://www.wikidata.org/prop/direct/P3762')]
# [('pname', 'SBN author ID'), ('p', 'http://www.wikidata.org/prop/direct/P396')]
# [('pname', 'Athenaeum person ID'), ('p', 'http://www.wikidata.org/prop/direct/P4145')]
# [('pname', 'YCBA agent ID'), ('p', 'http://www.wikidata.org/prop/direct/P4169')]
# [('pname', "Christie's creator ID"), ('p', 'http://www.wikidata.org/prop/direct/P4200')]
# [('pname', 'Bashkir encyclopedia (Russian version) ID'), ('p', 'http://www.wikidata.org/prop/direct/P4211')]
# [('pname', 'PACTOLS thesaurus ID'), ('p', 'http://www.wikidata.org/prop/direct/P4212')]
# [('pname', 'PM20 folder ID'), ('p', 'http://www.wikidata.org/prop/direct/P4293')]
# [('pname', 'AKL Online artist ID'), ('p', 'http://www.wikidata.org/prop/direct/P4432')]
# [('pname', 'ARLIMA ID'), ('p', 'http://www.wikidata.org/prop/direct/P4549')]
# [('pname', 'RA Collections ID'), ('p', 'http://www.wikidata.org/prop/direct/P4553')]
# [('pname', 'Online Books Page author ID'), ('p', 'http://www.wikidata.org/prop/direct/P4629')]
# [('pname', 'Royal Academy new identifier'), ('p', 'http://www.wikidata.org/prop/direct/P4808')]
# [('pname', 'PARES ID'), ('p', 'http://www.wikidata.org/prop/direct/P4813')]
# [('pname', 'patronym or matronym for this person'), ('p', 'http://www.wikidata.org/prop/direct/P5056')]
# [('pname', 'Interlingual Index ID'), ('p', 'http://www.wikidata.org/prop/direct/P5063')]
# [('pname', 'Behind The Voice Actors character ID'), ('p', 'http://www.wikidata.org/prop/direct/P5107')]
# [('pname', 'BIU Santé person ID'), ('p', 'http://www.wikidata.org/prop/direct/P5375')]
# [('pname', 'Trading Card Database person ID'), ('p', 'http://www.wikidata.org/prop/direct/P5421')]
# [('pname', 'Pontificia Università della Santa Croce ID'), ('p', 'http://www.wikidata.org/prop/direct/P5739')]
# [('pname', 'Encyclopedia Virginia ID'), ('p', 'http://www.wikidata.org/prop/direct/P5981')]
# [('pname', 'Larousse ID'), ('p', 'http://www.wikidata.org/prop/direct/P6058')]
# [('pname', 'Goodreads character ID'), ('p', 'http://www.wikidata.org/prop/direct/P6327')]
# [('pname', 'RKDartists ID'), ('p', 'http://www.wikidata.org/prop/direct/P650')]
# [('pname', 'Biografisch Portaal van Nederland ID'), ('p', 'http://www.wikidata.org/prop/direct/P651')]
# [('pname', 'BHCL ID (former scheme)'), ('p', 'http://www.wikidata.org/prop/direct/P6656')]
# [('pname', 'Alexander Turnbull Library ID'), ('p', 'http://www.wikidata.org/prop/direct/P6683')]
# [('pname', 'Uppsala University Alvin ID'), ('p', 'http://www.wikidata.org/prop/direct/P6821')]
# [('pname', 'Pinakes author ID'), ('p', 'http://www.wikidata.org/prop/direct/P6831')]
# [('pname', 'abART person ID'), ('p', 'http://www.wikidata.org/prop/direct/P6844')]
# [('pname', 'National Library of Russia ID'), ('p', 'http://www.wikidata.org/prop/direct/P7029')]
# [('pname', 'Documenta Catholica Omnia author ID'), ('p', 'http://www.wikidata.org/prop/direct/P7038')]
# [('pname', 'LyricsTranslate ID'), ('p', 'http://www.wikidata.org/prop/direct/P7212')]
# [('pname', 'National Library of Chile ID'), ('p', 'http://www.wikidata.org/prop/direct/P7369')]
# [('pname', 'Great Encyclopedia of Navarre ID'), ('p', 'http://www.wikidata.org/prop/direct/P7388')]
# [('pname', 'Rijksmuseum Research Library authority ID'), ('p', 'http://www.wikidata.org/prop/direct/P7444')]
# [('pname', 'Visuotinė lietuvių enciklopedija ID'), ('p', 'http://www.wikidata.org/prop/direct/P7666')]
# [('pname', 'National Library of Lithuania ID'), ('p', 'http://www.wikidata.org/prop/direct/P7699')]
# [('pname', 'Europeana entity'), ('p', 'http://www.wikidata.org/prop/direct/P7704')]
# [('pname', 'Spanish Vikidia ID'), ('p', 'http://www.wikidata.org/prop/direct/P7827')]
# [('pname', 'Frick Art Reference Library Photoarchive ID'), ('p', 'http://www.wikidata.org/prop/direct/P7848')]
# [('pname', 'Corpus Corporum author ID'), ('p', 'http://www.wikidata.org/prop/direct/P7935')]
# [('pname', 'Hrvatska enciklopedija ID'), ('p', 'http://www.wikidata.org/prop/direct/P7982')]
# [('pname', 'Mirabile author ID'), ('p', 'http://www.wikidata.org/prop/direct/P7986')]
# [('pname', 'Ökumenisches Heiligenlexikon ID'), ('p', 'http://www.wikidata.org/prop/direct/P8080')]
# [('pname', 'GeneaStar person ID'), ('p', 'http://www.wikidata.org/prop/direct/P8094')]
# [('pname', 'Canadiana NCF ID'), ('p', 'http://www.wikidata.org/prop/direct/P8179')]
# [('pname', 'National Library of Israel J9U ID'), ('p', 'http://www.wikidata.org/prop/direct/P8189')]
# [('pname', 'Philadelphia Museum of Art entity ID'), ('p', 'http://www.wikidata.org/prop/direct/P8317')]
# [('pname', 'Proleksis enciklopedija ID'), ('p', 'http://www.wikidata.org/prop/direct/P8349')]
# [('pname', 'GCatholic person ID'), ('p', 'http://www.wikidata.org/prop/direct/P8366')]
# [('pname', 'IMSLP ID'), ('p', 'http://www.wikidata.org/prop/direct/P839')]
# [('pname', 'KBpedia ID'), ('p', 'http://www.wikidata.org/prop/direct/P8408')]
# [('pname', 'Archive Site Trinity College Cambridge ID'), ('p', 'http://www.wikidata.org/prop/direct/P8496')]
# [('pname', 'anthem'), ('p', 'http://www.wikidata.org/prop/direct/P85')]
# [('pname', 'BMLO ID'), ('p', 'http://www.wikidata.org/prop/direct/P865')]
# [('pname', 'Unione Romana Biblioteche Scientifiche ID'), ('p', 'http://www.wikidata.org/prop/direct/P8750')]
# [('pname', 'General Diamond Catalogue ID'), ('p', 'http://www.wikidata.org/prop/direct/P8795')]
# [('pname', 'edition humboldt digital ID'), ('p', 'http://www.wikidata.org/prop/direct/P8826')]
# [('pname', 'Archives at Yale names ID'), ('p', 'http://www.wikidata.org/prop/direct/P8902')]
# [('pname', 'Museo Galileo authority ID'), ('p', 'http://www.wikidata.org/prop/direct/P8947')]
# [('pname', 'Pontificio Istituto di Archeologia Cristiana ID'), ('p', 'http://www.wikidata.org/prop/direct/P8982')]
# [('pname', 'HDS ID'), ('p', 'http://www.wikidata.org/prop/direct/P902')]
# [('pname', 'American Academy in Rome ID'), ('p', 'http://www.wikidata.org/prop/direct/P9097')]
# [('pname', 'Oxford Classical Dictionary ID'), ('p', 'http://www.wikidata.org/prop/direct/P9106')]
# [('pname', 'Biblioteca Iglesia Nacional Española en Roma ID'), ('p', 'http://www.wikidata.org/prop/direct/P9179')]
# [('pname', 'Provenio UUID'), ('p', 'http://www.wikidata.org/prop/direct/P9223')]
# [('pname', 'ARAE ID'), ('p', 'http://www.wikidata.org/prop/direct/P9226')]
# [('pname', 'Stadtlexikon Karlsruhe ID'), ('p', 'http://www.wikidata.org/prop/direct/P9285')]
# [('pname', 'Commons gallery'), ('p', 'http://www.wikidata.org/prop/direct/P935')]
# [('pname', 'National Library of Israel ID'), ('p', 'http://www.wikidata.org/prop/direct/P949')]
# [('pname', 'artist files at'), ('p', 'http://www.wikidata.org/prop/direct/P9493')]
# [('pname', 'National Historical Museums of Sweden agent ID'), ('p', 'http://www.wikidata.org/prop/direct/P9495')]
# [('pname', 'Biblioteca Nacional de España ID'), ('p', 'http://www.wikidata.org/prop/direct/P950')]
# [('pname', 'Podchaser creator ID'), ('p', 'http://www.wikidata.org/prop/direct/P9743')]
# [('pname', 'Schoenberg Database of Manuscripts name ID'), ('p', 'http://www.wikidata.org/prop/direct/P9756')]
# [('pname', 'armament'), ('p', 'http://www.wikidata.org/prop/direct/P520')]
# [('pname', 'Hansard (1803–2005) ID'), ('p', 'http://www.wikidata.org/prop/direct/P2015')]
# [('pname', "The Women's Print History Project person ID"), ('p', 'http://www.wikidata.org/prop/direct/P9780')]
# [('pname', 'home world'), ('p', 'http://www.wikidata.org/prop/direct/P1165')]
# [('pname', 'applies to jurisdiction'), ('p', 'http://www.wikidata.org/prop/direct/P1001')]
# [('pname', 'political ideology'), ('p', 'http://www.wikidata.org/prop/direct/P1142')]
# [('pname', 'U.S. National Archives Identifier'), ('p', 'http://www.wikidata.org/prop/direct/P1225')]
# [('pname', 'named after'), ('p', 'http://www.wikidata.org/prop/direct/P138')]
# [('pname', 'Commons Creator page'), ('p', 'http://www.wikidata.org/prop/direct/P1472')]
# [('pname', 'follows'), ('p', 'http://www.wikidata.org/prop/direct/P155')]
# [('pname', 'followed by'), ('p', 'http://www.wikidata.org/prop/direct/P156')]
# [('pname', 'country'), ('p', 'http://www.wikidata.org/prop/direct/P17')]
# [('pname', 'Les Archives du Spectacle Person ID'), ('p', 'http://www.wikidata.org/prop/direct/P1977')]
# [('pname', 'uses'), ('p', 'http://www.wikidata.org/prop/direct/P2283')]
# [('pname', 'Six Degrees of Francis Bacon ID'), ('p', 'http://www.wikidata.org/prop/direct/P2401')]
# [('pname', 'place of detention'), ('p', 'http://www.wikidata.org/prop/direct/P2632')]
# [('pname', 'subclass of'), ('p', 'http://www.wikidata.org/prop/direct/P279')]
# [('pname', 'DAHR artist ID'), ('p', 'http://www.wikidata.org/prop/direct/P4457')]
# [('pname', 'Collective Biographies of Women ID'), ('p', 'http://www.wikidata.org/prop/direct/P4539')]
# [('pname', 'Wolfram Language entity code'), ('p', 'http://www.wikidata.org/prop/direct/P4839')]
# [('pname', 'Giant Bomb ID'), ('p', 'http://www.wikidata.org/prop/direct/P5247')]
# [('pname', 'RegiowikiAT ID'), ('p', 'http://www.wikidata.org/prop/direct/P6228')]
# [('pname', 'Fandom article ID'), ('p', 'http://www.wikidata.org/prop/direct/P6262')]
# [('pname', 'Hymnary author ID'), ('p', 'http://www.wikidata.org/prop/direct/P6300')]
# [('pname', 'has works in the collection'), ('p', 'http://www.wikidata.org/prop/direct/P6379')]
# [('pname', 'V&A person ID'), ('p', 'http://www.wikidata.org/prop/direct/P6764')]
# [('pname', 'related image'), ('p', 'http://www.wikidata.org/prop/direct/P6802')]
# [('pname', 'The Top Tens ID'), ('p', 'http://www.wikidata.org/prop/direct/P7157')]
# [('pname', 'French Vikidia ID'), ('p', 'http://www.wikidata.org/prop/direct/P7818')]
# [('pname', 'Vienna History Wiki ID'), ('p', 'http://www.wikidata.org/prop/direct/P7842')]
# [('pname', 'student'), ('p', 'http://www.wikidata.org/prop/direct/P802')]
# [('pname', 'Internetowy Polski Słownik Biograficzny ID'), ('p', 'http://www.wikidata.org/prop/direct/P8130')]
# [('pname', 'LiederNet author ID'), ('p', 'http://www.wikidata.org/prop/direct/P8234')]
# [('pname', 'Dansk Biografisk Leksikon ID'), ('p', 'http://www.wikidata.org/prop/direct/P8341')]
# [('pname', 'Carl-Maria-von-Weber-Gesamtausgabe ID'), ('p', 'http://www.wikidata.org/prop/direct/P8589')]
# [('pname', 'McClintock and Strong Biblical Cyclopedia ID'), ('p', 'http://www.wikidata.org/prop/direct/P8636')]
# [('pname', 'Museen Dresden article ID'), ('p', 'http://www.wikidata.org/prop/direct/P8653')]
# [('pname', 'Rheinland-Pfälzische Personendatenbank ID'), ('p', 'http://www.wikidata.org/prop/direct/P8748')]
# [('pname', 'IPA transcription'), ('p', 'http://www.wikidata.org/prop/direct/P898')]
# [('pname', 'Medieval Manuscripts in Oxford Libraries person ID'), ('p', 'http://www.wikidata.org/prop/direct/P9017')]
# [('pname', 'SEARCH on line catalogue ID'), ('p', 'http://www.wikidata.org/prop/direct/P9081')]
# [('pname', 'Biographical Dictionary of the Czech Lands ID'), ('p', 'http://www.wikidata.org/prop/direct/P9160')]
# [('pname', 'NBM authority ID'), ('p', 'http://www.wikidata.org/prop/direct/P9507')]
# [('pname', 'Star Wars Databank ID'), ('p', 'http://www.wikidata.org/prop/direct/P3798')]
# [('pname', 'Magyar életrajzi lexikon ID'), ('p', 'http://www.wikidata.org/prop/direct/P8998')]
# [('pname', 'officeholder'), ('p', 'http://www.wikidata.org/prop/direct/P1308')]
# [('pname', 'DVN ID'), ('p', 'http://www.wikidata.org/prop/direct/P1788')]
# [('pname', 'Wissens-Aggregator Mittelalter und Frühe Neuzeit ID'), ('p', 'http://www.wikidata.org/prop/direct/P9441')]
# [('pname', 'Hungarian National Namespace person ID'), ('p', 'http://www.wikidata.org/prop/direct/P6988')]
# [('pname', 'Data Collection of the Hungarian Peerage ID'), ('p', 'http://www.wikidata.org/prop/direct/P9129')]
# [('pname', 'appears in the form of'), ('p', 'http://www.wikidata.org/prop/direct/P4675')]
# [('pname', 'founded by'), ('p', 'http://www.wikidata.org/prop/direct/P112')]
# [('pname', 'CONOR.SI ID'), ('p', 'http://www.wikidata.org/prop/direct/P1280')]
# [('pname', 'godparent'), ('p', 'http://www.wikidata.org/prop/direct/P1290')]
# [('pname', 'participant in'), ('p', 'http://www.wikidata.org/prop/direct/P1344')]
# [('pname', 'has pet'), ('p', 'http://www.wikidata.org/prop/direct/P1429')]
# [('pname', 'based on'), ('p', 'http://www.wikidata.org/prop/direct/P144')]
# [('pname', 'lifestyle'), ('p', 'http://www.wikidata.org/prop/direct/P1576')]
# [('pname', 'GTAA ID'), ('p', 'http://www.wikidata.org/prop/direct/P1741')]
# [('pname', 'commemorative plaque image'), ('p', 'http://www.wikidata.org/prop/direct/P1801')]
# [('pname', 'AGORHA person/institution ID'), ('p', 'http://www.wikidata.org/prop/direct/P2342')]
# [('pname', 'subject has role'), ('p', 'http://www.wikidata.org/prop/direct/P2868')]
# [('pname', 'Treccani ID'), ('p', 'http://www.wikidata.org/prop/direct/P3365')]
# [('pname', 'SHARE Catalogue author ID'), ('p', 'http://www.wikidata.org/prop/direct/P3987')]
# [('pname', 'BHL creator ID'), ('p', 'http://www.wikidata.org/prop/direct/P4081')]
# [('pname', 'National Library of Brazil ID'), ('p', 'http://www.wikidata.org/prop/direct/P4619')]
# [('pname', 'country of origin'), ('p', 'http://www.wikidata.org/prop/direct/P495')]
# [('pname', 'Norsk biografisk leksikon ID'), ('p', 'http://www.wikidata.org/prop/direct/P5080')]
# [('pname', 'EDIT16 catalogue author ID'), ('p', 'http://www.wikidata.org/prop/direct/P5492')]
# [('pname', 'Evene ID'), ('p', 'http://www.wikidata.org/prop/direct/P5617')]
# [('pname', 'Angelicum ID'), ('p', 'http://www.wikidata.org/prop/direct/P5731')]
# [('pname', 'ArhivX LOD'), ('p', 'http://www.wikidata.org/prop/direct/P5821')]
# [('pname', 'Muziekweb performer ID'), ('p', 'http://www.wikidata.org/prop/direct/P5882')]
# [('pname', 'MoEML ID'), ('p', 'http://www.wikidata.org/prop/direct/P6060')]
# [('pname', 'religious order'), ('p', 'http://www.wikidata.org/prop/direct/P611')]
# [('pname', 'Dictionnaire de spiritualité ID'), ('p', 'http://www.wikidata.org/prop/direct/P6302')]
# [('pname', 'ELNET ID'), ('p', 'http://www.wikidata.org/prop/direct/P6394')]
# [('pname', 'IntraText author ID'), ('p', 'http://www.wikidata.org/prop/direct/P6873')]
# [('pname', 'writing language'), ('p', 'http://www.wikidata.org/prop/direct/P6886')]
# [('pname', 'National Library of Iceland ID'), ('p', 'http://www.wikidata.org/prop/direct/P7039')]
# [('pname', 'Gazetteer for Scotland person ID'), ('p', 'http://www.wikidata.org/prop/direct/P7349')]
# [('pname', 'Slovak National Library ID (VIAF)'), ('p', 'http://www.wikidata.org/prop/direct/P7700')]
# [('pname', 'BeWeb person ID'), ('p', 'http://www.wikidata.org/prop/direct/P7796')]
# [('pname', 'DLL Catalog author ID'), ('p', 'http://www.wikidata.org/prop/direct/P8122')]
# [('pname', 'Grove Art Online ID'), ('p', 'http://www.wikidata.org/prop/direct/P8406')]
# [('pname', 'BHF author ID'), ('p', 'http://www.wikidata.org/prop/direct/P8547')]
# [('pname', 'Jewish Virtual Library ID'), ('p', 'http://www.wikidata.org/prop/direct/P8568')]
# [('pname', 'CONOR.SR ID'), ('p', 'http://www.wikidata.org/prop/direct/P8851')]
# [('pname', 'Cyprus University of Technology ID'), ('p', 'http://www.wikidata.org/prop/direct/P9251')]
# [('pname', 'Catalogue of the Capitular Library of Verona author ID'), ('p', 'http://www.wikidata.org/prop/direct/P9282')]
# [('pname', 'Cyprus Bibliography ID'), ('p', 'http://www.wikidata.org/prop/direct/P9287')]
# [('pname', 'Biblioteche della Custodia di Terra Santa a Gerusalemme ID'), ('p', 'http://www.wikidata.org/prop/direct/P9534')]
# [('pname', 'SNK ID'), ('p', 'http://www.wikidata.org/prop/direct/P9807')]
# [('pname', 'Catholic Hierarchy person ID'), ('p', 'http://www.wikidata.org/prop/direct/P1047')]
# [('pname', 'PIM authority ID'), ('p', 'http://www.wikidata.org/prop/direct/P3973')]
# [('pname', 'The Cardinals of the Holy Roman Church ID'), ('p', 'http://www.wikidata.org/prop/direct/P7619')]
# [('pname', 'Clavis Clavium ID'), ('p', 'http://www.wikidata.org/prop/direct/P7908')]
# [('pname', 'copyright holder'), ('p', 'http://www.wikidata.org/prop/direct/P3931')]
# [('pname', 'fictional analog of'), ('p', 'http://www.wikidata.org/prop/direct/P1074')]
# [('pname', 'sitter'), ('p', 'http://www.wikidata.org/prop/direct/P2634')]
# [('pname', 'has quality'), ('p', 'http://www.wikidata.org/prop/direct/P1552')]
# [('pname', 'ECARTICO person ID'), ('p', 'http://www.wikidata.org/prop/direct/P2915')]
# [('pname', 'Artnet artist ID'), ('p', 'http://www.wikidata.org/prop/direct/P3782')]
# [('pname', 'BNMM authority ID'), ('p', 'http://www.wikidata.org/prop/direct/P3788')]
# [('pname', 'BDCYL authority ID'), ('p', 'http://www.wikidata.org/prop/direct/P3964')]
# [('pname', 'academic degree'), ('p', 'http://www.wikidata.org/prop/direct/P512')]
# [('pname', 'ancestral home'), ('p', 'http://www.wikidata.org/prop/direct/P66')]
# [('pname', 'BlackPast.org ID'), ('p', 'http://www.wikidata.org/prop/direct/P6723')]
# [('pname', 'academic major'), ('p', 'http://www.wikidata.org/prop/direct/P812')]
# [('pname', 'Encyclopédie berbère article ID'), ('p', 'http://www.wikidata.org/prop/direct/P9198')]
# [('pname', 'allegiance'), ('p', 'http://www.wikidata.org/prop/direct/P945')]
# [('pname', 'SAIA authority ID'), ('p', 'http://www.wikidata.org/prop/direct/P9536')]
# [('pname', 'official residence'), ('p', 'http://www.wikidata.org/prop/direct/P263')]
# [('pname', 'Dictionnaire des femmes de l’ancienne France ID'), ('p', 'http://www.wikidata.org/prop/direct/P7962')]
# [('pname', 'Premiers préfets ID'), ('p', 'http://www.wikidata.org/prop/direct/P4944')]
# [('pname', 'Bargeton ID'), ('p', 'http://www.wikidata.org/prop/direct/P4906')]
# [('pname', 'incarnation of'), ('p', 'http://www.wikidata.org/prop/direct/P3701')]
# [('pname', 'National Library of Romania ID'), ('p', 'http://www.wikidata.org/prop/direct/P1003')]
# [('pname', 'honorific suffix'), ('p', 'http://www.wikidata.org/prop/direct/P1035')]
# [('pname', 'Regensburg Classification'), ('p', 'http://www.wikidata.org/prop/direct/P1150')]
# [('pname', 'publisher'), ('p', 'http://www.wikidata.org/prop/direct/P123')]
# [('pname', 'OmegaWiki Defined Meaning'), ('p', 'http://www.wikidata.org/prop/direct/P1245')]
# [('pname', 'EGAXA ID'), ('p', 'http://www.wikidata.org/prop/direct/P1309')]
# [('pname', "topic's main template"), ('p', 'http://www.wikidata.org/prop/direct/P1424')]
# [('pname', 'nickname'), ('p', 'http://www.wikidata.org/prop/direct/P1449')]
# [('pname', 'zbMATH author ID'), ('p', 'http://www.wikidata.org/prop/direct/P1556')]
# [('pname', 'MacTutor biography ID'), ('p', 'http://www.wikidata.org/prop/direct/P1563')]
# [('pname', 'date of baptism in early childhood'), ('p', 'http://www.wikidata.org/prop/direct/P1636')]
# [('pname', 'doctoral advisor'), ('p', 'http://www.wikidata.org/prop/direct/P184')]
# [('pname', 'doctoral student'), ('p', 'http://www.wikidata.org/prop/direct/P185')]
# [('pname', 'LibriVox author ID'), ('p', 'http://www.wikidata.org/prop/direct/P1899')]
# [('pname', 'Project Gutenberg author ID'), ('p', 'http://www.wikidata.org/prop/direct/P1938')]
# [('pname', 'history of topic'), ('p', 'http://www.wikidata.org/prop/direct/P2184')]
# [('pname', 'Hederich encyclopedia article ID'), ('p', 'http://www.wikidata.org/prop/direct/P2272')]
# [('pname', 'Roman praenomen'), ('p', 'http://www.wikidata.org/prop/direct/P2358')]
# [('pname', 'CTHS person ID'), ('p', 'http://www.wikidata.org/prop/direct/P2383')]
# [('pname', 'J. Paul Getty Museum artist id'), ('p', 'http://www.wikidata.org/prop/direct/P2432')]
# [('pname', 'culture'), ('p', 'http://www.wikidata.org/prop/direct/P2596')]
# [('pname', 'Cultureel Woordenboek ID'), ('p', 'http://www.wikidata.org/prop/direct/P3569')]
# [('pname', 'DBC author ID'), ('p', 'http://www.wikidata.org/prop/direct/P3846')]
# [('pname', 'Open Library subject ID'), ('p', 'http://www.wikidata.org/prop/direct/P3847')]
# [('pname', 'National Academy of Medicine (France) member ID'), ('p', 'http://www.wikidata.org/prop/direct/P3956')]
# [('pname', 'Bridgeman artist ID'), ('p', 'http://www.wikidata.org/prop/direct/P3965')]
# [('pname', "Treccani's Enciclopedia Italiana ID"), ('p', 'http://www.wikidata.org/prop/direct/P4223')]
# [('pname', 'Académie française member ID'), ('p', 'http://www.wikidata.org/prop/direct/P4717')]
# [('pname', 'Maitron ID'), ('p', 'http://www.wikidata.org/prop/direct/P4724')]
# [('pname', 'archives at'), ('p', 'http://www.wikidata.org/prop/direct/P485')]
# [('pname', 'MR Author ID'), ('p', 'http://www.wikidata.org/prop/direct/P4955')]
# [('pname', 'TMDb person ID'), ('p', 'http://www.wikidata.org/prop/direct/P4985')]
# [('pname', 'BNB person ID'), ('p', 'http://www.wikidata.org/prop/direct/P5361')]
# [('pname', 'Classiques des sciences sociales ID'), ('p', 'http://www.wikidata.org/prop/direct/P5390')]
# [('pname', 'Mathematics Genealogy Project ID'), ('p', 'http://www.wikidata.org/prop/direct/P549')]
# [('pname', 'bgm.tv character ID'), ('p', 'http://www.wikidata.org/prop/direct/P6296')]
# [('pname', 'Léonore ID'), ('p', 'http://www.wikidata.org/prop/direct/P640')]
# [('pname', 'sport'), ('p', 'http://www.wikidata.org/prop/direct/P641')]
# [('pname', 'Lebanese National Library ID'), ('p', 'http://www.wikidata.org/prop/direct/P7026')]
# [('pname', 'Online PWN Encyclopedia ID'), ('p', 'http://www.wikidata.org/prop/direct/P7305')]
# [('pname', 'influenced by'), ('p', 'http://www.wikidata.org/prop/direct/P737')]
# [('pname', 'DUC ID'), ('p', 'http://www.wikidata.org/prop/direct/P7578')]
# [('pname', 'Fichier des personnes décédées ID (matchID)'), ('p', 'http://www.wikidata.org/prop/direct/P9058')]
# [('pname', 'Archivo Linz de la Transición Española ID'), ('p', 'http://www.wikidata.org/prop/direct/P9231')]
# [('pname', 'Biblioteca di Santa Sabina ID'), ('p', 'http://www.wikidata.org/prop/direct/P9522')]
# [('pname', "Treccani's Enciclopedia della Matematica ID"), ('p', 'http://www.wikidata.org/prop/direct/P9621')]
# [('pname', 'Bod-Inc Online author ID'), ('p', 'http://www.wikidata.org/prop/direct/P9653')]
# [('pname', 'MANTO ID'), ('p', 'http://www.wikidata.org/prop/direct/P9736')]
# [('pname', 'DC character ID'), ('p', 'http://www.wikidata.org/prop/direct/P9851')]
# [('pname', 'École normale alumnus ID'), ('p', 'http://www.wikidata.org/prop/direct/P5373')]
# [('pname', 'Swedish Open Cultural Heritage URI'), ('p', 'http://www.wikidata.org/prop/direct/P1260')]
# [('pname', 'military casualty classification'), ('p', 'http://www.wikidata.org/prop/direct/P1347')]
# [('pname', 'ranking'), ('p', 'http://www.wikidata.org/prop/direct/P1352')]
# [('pname', 'Global Anabaptist Mennonite Encyclopedia Online ID'), ('p', 'http://www.wikidata.org/prop/direct/P1842')]
# [('pname', 'Kansallisbiografia ID'), ('p', 'http://www.wikidata.org/prop/direct/P2180')]
# [('pname', 'ODIS ID'), ('p', 'http://www.wikidata.org/prop/direct/P2372')]
# [('pname', 'WomenWriters ID'), ('p', 'http://www.wikidata.org/prop/direct/P2533')]
# [('pname', 'BabelNet ID'), ('p', 'http://www.wikidata.org/prop/direct/P2581')]
# [('pname', 'CALIS ID'), ('p', 'http://www.wikidata.org/prop/direct/P270')]
# [('pname', 'Benezit ID'), ('p', 'http://www.wikidata.org/prop/direct/P2843')]
# [('pname', 'permanent duplicated item'), ('p', 'http://www.wikidata.org/prop/direct/P2959')]
# [('pname', 'Biografiskt Lexikon för Finland ID'), ('p', 'http://www.wikidata.org/prop/direct/P3595')]
# [('pname', 'gravsted.dk ID'), ('p', 'http://www.wikidata.org/prop/direct/P4359')]
# [('pname', 'Städel Museum artist ID'), ('p', 'http://www.wikidata.org/prop/direct/P4581')]
# [('pname', 'Chinese Political Elites Database ID'), ('p', 'http://www.wikidata.org/prop/direct/P5142')]
# [('pname', 'LONSEA ID'), ('p', 'http://www.wikidata.org/prop/direct/P5306')]
# [('pname', 'Bibliothèque de la Pléiade ID'), ('p', 'http://www.wikidata.org/prop/direct/P5613')]
# [('pname', 'Biographie nationale de Belgique ID'), ('p', 'http://www.wikidata.org/prop/direct/P6234')]
# [('pname', 'Image Archive, Herder Institute'), ('p', 'http://www.wikidata.org/prop/direct/P6482')]
# [('pname', 'Klexikon article ID'), ('p', 'http://www.wikidata.org/prop/direct/P6573')]
# [('pname', 'TV Tropes identifier'), ('p', 'http://www.wikidata.org/prop/direct/P6839')]
# [('pname', 'Hoopla artist ID'), ('p', 'http://www.wikidata.org/prop/direct/P6868')]
# [('pname', 'NicoNicoPedia ID'), ('p', 'http://www.wikidata.org/prop/direct/P6900')]
# [('pname', 'PHI Latin Texts author ID'), ('p', 'http://www.wikidata.org/prop/direct/P6941')]
# [('pname', 'Musisque Deoque author ID'), ('p', 'http://www.wikidata.org/prop/direct/P6999')]
# [('pname', 'Flemish Public Libraries ID'), ('p', 'http://www.wikidata.org/prop/direct/P7024')]
# [('pname', 'Perseus author ID'), ('p', 'http://www.wikidata.org/prop/direct/P7041')]
# [('pname', 'The Latin Library author ID'), ('p', 'http://www.wikidata.org/prop/direct/P7042')]
# [('pname', 'pseudonym'), ('p', 'http://www.wikidata.org/prop/direct/P742')]
# [('pname', "Edvard Munch's correspondance person ID"), ('p', 'http://www.wikidata.org/prop/direct/P7466')]
# [('pname', 'Naver Encyclopedia ID'), ('p', 'http://www.wikidata.org/prop/direct/P7506')]
# [('pname', 'Ben Yehuda author ID'), ('p', 'http://www.wikidata.org/prop/direct/P7507')]
# [('pname', 'Joconde author ID'), ('p', 'http://www.wikidata.org/prop/direct/P7711')]
# [('pname', 'Projekt Gutenberg-DE ID'), ('p', 'http://www.wikidata.org/prop/direct/P7753')]
# [('pname', 'Italian Vikidia ID'), ('p', 'http://www.wikidata.org/prop/direct/P7822')]
# [('pname', 'English Vikidia ID'), ('p', 'http://www.wikidata.org/prop/direct/P7829')]
# [('pname', 'Basque Vikidia ID'), ('p', 'http://www.wikidata.org/prop/direct/P7832')]
# [('pname', 'CoBiS author ID'), ('p', 'http://www.wikidata.org/prop/direct/P7865')]
# [('pname', 'category for maps'), ('p', 'http://www.wikidata.org/prop/direct/P7867')]
# [('pname', 'Frankfurter Personenlexikon ID'), ('p', 'http://www.wikidata.org/prop/direct/P8044')]
# [('pname', 'CIRIS author ID'), ('p', 'http://www.wikidata.org/prop/direct/P8065')]
# [('pname', 'Österreichisches Musiklexikon Online ID'), ('p', 'http://www.wikidata.org/prop/direct/P8432')]
# [('pname', 'Encyclopedie berbere keyword ID'), ('p', 'http://www.wikidata.org/prop/direct/P8472')]
# [('pname', 'monumenta.ch ID'), ('p', 'http://www.wikidata.org/prop/direct/P8566')]
# ...
# [('pname', 'GMC registration number'), ('p', 'http://www.wikidata.org/prop/direct/P8273')]
# [('pname', 'Reprezentacija player ID'), ('p', 'http://www.wikidata.org/prop/direct/P3908')]
# [('pname', 'document file on Wikimedia Commons'), ('p', 'http://www.wikidata.org/prop/direct/P996')]
# [('pname', 'Deutsche Ultramarathon-Vereinigung ID'), ('p', 'http://www.wikidata.org/prop/direct/P2162')]
# [('pname', 'ITRA runner ID'), ('p', 'http://www.wikidata.org/prop/direct/P3584')]
# [('pname', 'UltraSignup runner ID'), ('p', 'http://www.wikidata.org/prop/direct/P3585')]
# [('pname', 'Israel Chess Federation player ID'), ('p', 'http://www.wikidata.org/prop/direct/P3867')]
# [('pname', 'PatientsLikeMe treatment ID'), ('p', 'http://www.wikidata.org/prop/direct/P4235')]
# [('pname', 'Dominicains ID'), ('p', 'http://www.wikidata.org/prop/direct/P4943')]
# [('pname', 'CurlingZone ID'), ('p', 'http://www.wikidata.org/prop/direct/P3556')]
# [('pname', 'Curling.fi player ID'), ('p', 'http://www.wikidata.org/prop/direct/P9166')]
# [('pname', "Encyclopédie du patrimoine culturel de l'Amérique française ID (French)"), ('p', 'http://www.wikidata.org/prop/direct/P9292')]
# [('pname', 'SISSCO ID'), ('p', 'http://www.wikidata.org/prop/direct/P9111')]
# [('pname', 'Online Begraafplaatsen person ID'), ('p', 'http://www.wikidata.org/prop/direct/P9890')]
# [('pname', "OlimpBase Women's Chess Olympiad player ID"), ('p', 'http://www.wikidata.org/prop/direct/P5224')]
# [('pname', '90minut player ID'), ('p', 'http://www.wikidata.org/prop/direct/P3605')]
# [('pname', 'Fach'), ('p', 'http://www.wikidata.org/prop/direct/P1731')]
# [('pname', 'Europeana Fashion creator ID'), ('p', 'http://www.wikidata.org/prop/direct/P3482')]
# [('pname', 'J! Archive player ID'), ('p', 'http://www.wikidata.org/prop/direct/P9484')]
# [('pname', 'valid in period'), ('p', 'http://www.wikidata.org/prop/direct/P1264')]
# [('pname', "Debrett's People of Today ID"), ('p', 'http://www.wikidata.org/prop/direct/P2255')]
# [('pname', 'Black Ferns player ID'), ('p', 'http://www.wikidata.org/prop/direct/P5636')]
# [('pname', 'IBSF athlete ID'), ('p', 'http://www.wikidata.org/prop/direct/P2991')]
# [('pname', 'Il Sole 24 Ore ID'), ('p', 'http://www.wikidata.org/prop/direct/P8136')]
# [('pname', 'parent organization'), ('p', 'http://www.wikidata.org/prop/direct/P749')]
# [('pname', 'substitute/deputy/replacement of office/officeholder'), ('p', 'http://www.wikidata.org/prop/direct/P2098')]
# [('pname', 'category contains'), ('p', 'http://www.wikidata.org/prop/direct/P4224')]
# [('pname', 'multi-channel network'), ('p', 'http://www.wikidata.org/prop/direct/P6540')]
# [('pname', 'French diocesan architects ID'), ('p', 'http://www.wikidata.org/prop/direct/P2385')]
# [('pname', 'endorsed by'), ('p', 'http://www.wikidata.org/prop/direct/P8001')]
# [('pname', 'Indiana Basketball Hall of Fame ID'), ('p', 'http://www.wikidata.org/prop/direct/P4557')]
# [('pname', '08euro.Ru person ID'), ('p', 'http://www.wikidata.org/prop/direct/P7111')]
# [('pname', 'official religion'), ('p', 'http://www.wikidata.org/prop/direct/P3075')]
# [('pname', 'Red Bull athlete ID'), ('p', 'http://www.wikidata.org/prop/direct/P3883')]
# [('pname', 'WorldSBK.com racer identifier'), ('p', 'http://www.wikidata.org/prop/direct/P4076')]
# [('pname', 'Google News publication ID'), ('p', 'http://www.wikidata.org/prop/direct/P6157')]
# [('pname', 'Institut culturel de Bretagne ID'), ('p', 'http://www.wikidata.org/prop/direct/P5561')]
# [('pname', 'Flanders Arts Institute organisation ID'), ('p', 'http://www.wikidata.org/prop/direct/P5164')]
# [('pname', 'La Vie des idées ID'), ('p', 'http://www.wikidata.org/prop/direct/P5550')]
# [('pname', 'stated as'), ('p', 'http://www.wikidata.org/prop/direct/P1932')]
# [('pname', 'GUI number'), ('p', 'http://www.wikidata.org/prop/direct/P7729')]
# [('pname', 'Thesaurus Sozialwissenschaften ID'), ('p', 'http://www.wikidata.org/prop/direct/P8365')]
# [('pname', 'Polish Basketball League ID'), ('p', 'http://www.wikidata.org/prop/direct/P5723')]
# [('pname', 'Danish Football Union player ID'), ('p', 'http://www.wikidata.org/prop/direct/P6109')]
# [('pname', 'California Sports Hall of Fame athlete ID'), ('p', 'http://www.wikidata.org/prop/direct/P4507')]
# [('pname', 'United States Olympic & Paralympic Committee athlete ID'), ('p', 'http://www.wikidata.org/prop/direct/P4063')]
# [('pname', 'UIPM athlete ID'), ('p', 'http://www.wikidata.org/prop/direct/P2726')]
# [('pname', 'number of victims of killer'), ('p', 'http://www.wikidata.org/prop/direct/P1345')]
# [('pname', 'Church of Jesus Christ pioneer ID'), ('p', 'http://www.wikidata.org/prop/direct/P8818')]
# [('pname', 'Rivals.com ID'), ('p', 'http://www.wikidata.org/prop/direct/P7339')]
# [('pname', '247Sports ID'), ('p', 'http://www.wikidata.org/prop/direct/P7397')]
# [('pname', 'Japan Sumo Association ID'), ('p', 'http://www.wikidata.org/prop/direct/P3385')]
# [('pname', 'RollDaBeats artist ID'), ('p', 'http://www.wikidata.org/prop/direct/P5240')]
# [('pname', 'AWARE ID'), ('p', 'http://www.wikidata.org/prop/direct/P6637')]
# [('pname', 'GitLab username'), ('p', 'http://www.wikidata.org/prop/direct/P8827')]
# [('pname', 'defendant'), ('p', 'http://www.wikidata.org/prop/direct/P1591')]
# [('pname', 'relevant qualification'), ('p', 'http://www.wikidata.org/prop/direct/P4968')]
# [('pname', 'HistoryLink essay number'), ('p', 'http://www.wikidata.org/prop/direct/P9470')]
# [('pname', 'number of subscribers'), ('p', 'http://www.wikidata.org/prop/direct/P3744')]
# [('pname', 'Patreon ID'), ('p', 'http://www.wikidata.org/prop/direct/P4175')]
# [('pname', 'EU VAT number'), ('p', 'http://www.wikidata.org/prop/direct/P3608')]
# [('pname', 'EU Research participant ID'), ('p', 'http://www.wikidata.org/prop/direct/P5785')]
# [('pname', 'PremiershipRugby.com ID'), ('p', 'http://www.wikidata.org/prop/direct/P861')]
# [('pname', 'Commons compatible image available at URL'), ('p', 'http://www.wikidata.org/prop/direct/P4765')]
# [('pname', 'MLS player ID'), ('p', 'http://www.wikidata.org/prop/direct/P2398')]
# [('pname', 'LongSwimsDB ID'), ('p', 'http://www.wikidata.org/prop/direct/P7232')]
# [('pname', 'FIVB beach volleyball player ID'), ('p', 'http://www.wikidata.org/prop/direct/P2801')]
# [('pname', 'Tacoma Local History & Biography Index ID'), ('p', 'http://www.wikidata.org/prop/direct/P9406')]
# [('pname', 'VK artist ID'), ('p', 'http://www.wikidata.org/prop/direct/P9694')]
# [('pname', 'EncyclopediaPR ID'), ('p', 'http://www.wikidata.org/prop/direct/P9288')]
# [('pname', 'ICCF player ID'), ('p', 'http://www.wikidata.org/prop/direct/P3316')]
# [('pname', 'Shirat Nashim person ID'), ('p', 'http://www.wikidata.org/prop/direct/P4449')]
# [('pname', 'secretary general'), ('p', 'http://www.wikidata.org/prop/direct/P3975')]
# [('pname', 'Emporis company ID'), ('p', 'http://www.wikidata.org/prop/direct/P8563')]
# [('pname', 'ABA League ID'), ('p', 'http://www.wikidata.org/prop/direct/P6850')]
# [('pname', 'infosport.ru person ID'), ('p', 'http://www.wikidata.org/prop/direct/P6421')]
# [('pname', 'indigenous to'), ('p', 'http://www.wikidata.org/prop/direct/P2341')]
# [('pname', 'ProsopoMaths ID'), ('p', 'http://www.wikidata.org/prop/direct/P6037')]
# [('pname', 'Martindale-Hubbell profile'), ('p', 'http://www.wikidata.org/prop/direct/P6650')]
# [('pname', 'KSI player ID'), ('p', 'http://www.wikidata.org/prop/direct/P6495')]
# [('pname', 'supervisory board member'), ('p', 'http://www.wikidata.org/prop/direct/P5052')]
# [('pname', 'public key fingerprint'), ('p', 'http://www.wikidata.org/prop/direct/P3721')]
# [('pname', 'Skijumping.pl jumper ID'), ('p', 'http://www.wikidata.org/prop/direct/P5790')]
# [('pname', 'Arolsen ID'), ('p', 'http://www.wikidata.org/prop/direct/P7656')]
# [('pname', 'Canadian Ski Hall of Fame inductee ID'), ('p', 'http://www.wikidata.org/prop/direct/P4463')]
# [('pname', 'ACB.com coach ID'), ('p', 'http://www.wikidata.org/prop/direct/P6297')]
# [('pname', 'Rugby League Project player ID'), ('p', 'http://www.wikidata.org/prop/direct/P4464')]
# [('pname', 'Historical Marker Database ID'), ('p', 'http://www.wikidata.org/prop/direct/P7883')]
# [('pname', 'source of income'), ('p', 'http://www.wikidata.org/prop/direct/P2770')]
# [('pname', 'Barbarian R.C. ID'), ('p', 'http://www.wikidata.org/prop/direct/P4494')]
# [('pname', 'ecoregion (WWF)'), ('p', 'http://www.wikidata.org/prop/direct/P1425')]
# [('pname', 'CMI person ID'), ('p', 'http://www.wikidata.org/prop/direct/P5948')]
# [('pname', 'OpenDomesday person ID'), ('p', 'http://www.wikidata.org/prop/direct/P3122')]
# [('pname', 'Pontifical University of Salamanca ID'), ('p', 'http://www.wikidata.org/prop/direct/P9247')]
# [('pname', 'country of registry'), ('p', 'http://www.wikidata.org/prop/direct/P8047')]
# [('pname', 'trophy awarded'), ('p', 'http://www.wikidata.org/prop/direct/P4622')]
# [('pname', 'PermID'), ('p', 'http://www.wikidata.org/prop/direct/P3347')]
# [('pname', 'JWF Wrestlers Database person ID'), ('p', 'http://www.wikidata.org/prop/direct/P6502')]
# [('pname', 'FACR player ID'), ('p', 'http://www.wikidata.org/prop/direct/P3050')]
# [('pname', 'Oxford African American Studies Center ID'), ('p', 'http://www.wikidata.org/prop/direct/P9332')]
# [('pname', 'International World Games Association athlete ID'), ('p', 'http://www.wikidata.org/prop/direct/P4588')]
# [('pname', 'Karate Records ID'), ('p', 'http://www.wikidata.org/prop/direct/P2705')]
# [('pname', 'Présence Compositrices composer ID'), ('p', 'http://www.wikidata.org/prop/direct/P8523')]
# [('pname', 'Grove Music Online ID'), ('p', 'http://www.wikidata.org/prop/direct/P8591')]
# [('pname', 'Israel Football Association player ID'), ('p', 'http://www.wikidata.org/prop/direct/P3748')]
# [('pname', 'HNI person/institution ID'), ('p', 'http://www.wikidata.org/prop/direct/P2476')]
# [('pname', 'cast member'), ('p', 'http://www.wikidata.org/prop/direct/P161')]
# [('pname', 'Alabama Sports Hall of Fame athlete ID'), ('p', 'http://www.wikidata.org/prop/direct/P4362')]
# [('pname', 'Price One Penny publisher ID'), ('p', 'http://www.wikidata.org/prop/direct/P9624')]
# [('pname', 'Eldoblaje dubbing actor ID'), ('p', 'http://www.wikidata.org/prop/direct/P4681')]
# [('pname', 'Knesset Law ID'), ('p', 'http://www.wikidata.org/prop/direct/P7390')]
# [('pname', 'ChinesePosters artist ID'), ('p', 'http://www.wikidata.org/prop/direct/P4531')]
# [('pname', 'ARPI author ID'), ('p', 'http://www.wikidata.org/prop/direct/P9795')]
# [('pname', "Women's Sports Foundation ID"), ('p', 'http://www.wikidata.org/prop/direct/P4377')]
# [('pname', 'FIS snowboarder ID'), ('p', 'http://www.wikidata.org/prop/direct/P2777')]
# [('pname', 'Georgia Sports Hall of Fame ID'), ('p', 'http://www.wikidata.org/prop/direct/P4364')]
# [('pname', 'Lichess username'), ('p', 'http://www.wikidata.org/prop/direct/P8976')]
# [('pname', 'À nos grands hommes ID'), ('p', 'http://www.wikidata.org/prop/direct/P6141')]
# [('pname', 'FIL athlete ID'), ('p', 'http://www.wikidata.org/prop/direct/P2990')]
# [('pname', 'French Paralympic and Sports Committee athlete ID'), ('p', 'http://www.wikidata.org/prop/direct/P8797')]
# [('pname', 'ACB.com player ID'), ('p', 'http://www.wikidata.org/prop/direct/P3525')]
# [('pname', 'Blogger user profile ID'), ('p', 'http://www.wikidata.org/prop/direct/P8772')]
# [('pname', 'Luding designer ID'), ('p', 'http://www.wikidata.org/prop/direct/P3506')]
# [('pname', 'European Tour golf player ID'), ('p', 'http://www.wikidata.org/prop/direct/P3521')]
# [('pname', 'designed by'), ('p', 'http://www.wikidata.org/prop/direct/P287')]
# [('pname', 'Secondary Archive artist ID'), ('p', 'http://www.wikidata.org/prop/direct/P9539')]
# [('pname', 'academic appointment'), ('p', 'http://www.wikidata.org/prop/direct/P8413')]
# [('pname', 'short-track speed skater ISU ID'), ('p', 'http://www.wikidata.org/prop/direct/P3693')]
# [('pname', 'CharacTour character ID'), ('p', 'http://www.wikidata.org/prop/direct/P5863')]
# [('pname', 'Douban book version/edition ID'), ('p', 'http://www.wikidata.org/prop/direct/P6442')]
# [('pname', 'KLEKs ID'), ('p', 'http://www.wikidata.org/prop/direct/P5556')]
# [('pname', 'Enciclopedia dello Sport ID'), ('p', 'http://www.wikidata.org/prop/direct/P9873')]
# [('pname', 'MTV Germany artist ID'), ('p', 'http://www.wikidata.org/prop/direct/P7641')]
# [('pname', 'Nominis given name ID'), ('p', 'http://www.wikidata.org/prop/direct/P4284')]
# [('pname', 'British Museum bioID'), ('p', 'http://www.wikidata.org/prop/direct/P6077')]
# [('pname', 'Voetbalstats player ID'), ('p', 'http://www.wikidata.org/prop/direct/P5742')]
# [('pname', 'DZFoot.com player ID'), ('p', 'http://www.wikidata.org/prop/direct/P3658')]
# [('pname', 'Croatian Football Federation player ID'), ('p', 'http://www.wikidata.org/prop/direct/P3577')]
# [('pname', 'CRGPG ID'), ('p', 'http://www.wikidata.org/prop/direct/P8857')]
# [('pname', 're:publica speaker ID'), ('p', 'http://www.wikidata.org/prop/direct/P8148')]
# [('pname', 'academic minor'), ('p', 'http://www.wikidata.org/prop/direct/P811')]
# [('pname', 'WAFL FootyFacts ID'), ('p', 'http://www.wikidata.org/prop/direct/P4615')]
# [('pname', 'Whaling History ID'), ('p', 'http://www.wikidata.org/prop/direct/P7895')]
# [('pname', "Harper's author ID"), ('p', 'http://www.wikidata.org/prop/direct/P6784')]
# [('pname', 'Saskatchewan Sports Hall of Fame ID'), ('p', 'http://www.wikidata.org/prop/direct/P5690')]
# [('pname', 'sports competition competed at'), ('p', 'http://www.wikidata.org/prop/direct/P5249')]
# [('pname', 'AnimeCons.com guest ID'), ('p', 'http://www.wikidata.org/prop/direct/P3790')]
# [('pname', 'Amazon Standard Identification Number'), ('p', 'http://www.wikidata.org/prop/direct/P5749')]
# [('pname', 'panoramic view'), ('p', 'http://www.wikidata.org/prop/direct/P4291')]
# [('pname', 'Discogs release ID'), ('p', 'http://www.wikidata.org/prop/direct/P2206')]
# [('pname', 'IWF athlete ID'), ('p', 'http://www.wikidata.org/prop/direct/P3667')]
# [('pname', 'BoardGameGeek designer ID'), ('p', 'http://www.wikidata.org/prop/direct/P3505')]
# [('pname', 'FFF male player ID (former scheme)'), ('p', 'http://www.wikidata.org/prop/direct/P4883')]
# [('pname', 'main regulatory text'), ('p', 'http://www.wikidata.org/prop/direct/P92')]
# [('pname', 'FFF player ID (new scheme)'), ('p', 'http://www.wikidata.org/prop/direct/P9264')]
# [('pname', 'Czech Registration ID'), ('p', 'http://www.wikidata.org/prop/direct/P4156')]
# [('pname', 'LegaBasket.it coach ID'), ('p', 'http://www.wikidata.org/prop/direct/P5612')]
# [('pname', 'RealGM basketball coach ID'), ('p', 'http://www.wikidata.org/prop/direct/P7954')]
# [('pname', 'Global Poker Index ID'), ('p', 'http://www.wikidata.org/prop/direct/P3564')]
# [('pname', 'World Series of Poker ID'), ('p', 'http://www.wikidata.org/prop/direct/P3554')]
# [('pname', 'BDH edition ID'), ('p', 'http://www.wikidata.org/prop/direct/P4956')]
# [('pname', 'Google Books ID'), ('p', 'http://www.wikidata.org/prop/direct/P675')]
# [('pname', 'rector'), ('p', 'http://www.wikidata.org/prop/direct/P1075')]
# [('pname', 'Wikitribune category'), ('p', 'http://www.wikidata.org/prop/direct/P4973')]
# [('pname', 'party chief representative'), ('p', 'http://www.wikidata.org/prop/direct/P210')]
# [('pname', 'continent'), ('p', 'http://www.wikidata.org/prop/direct/P30')]
# [('pname', 'partially coincident with'), ('p', 'http://www.wikidata.org/prop/direct/P1382')]
# [('pname', 'Brapci author ID'), ('p', 'http://www.wikidata.org/prop/direct/P9452')]
# [('pname', 'tribunsdelaplebe.fr ID'), ('p', 'http://www.wikidata.org/prop/direct/P8961')]
# [('pname', 'Atlas Obscura identifier'), ('p', 'http://www.wikidata.org/prop/direct/P7772')]
# [('pname', 'SAH Archipedia architect ID'), ('p', 'http://www.wikidata.org/prop/direct/P8439')]
# [('pname', 'Strava ID of a professional sport person'), ('p', 'http://www.wikidata.org/prop/direct/P5283')]
# [('pname', 'OpenStreetMap numeric user ID'), ('p', 'http://www.wikidata.org/prop/direct/P8754')]
# [('pname', 'National Gallery of Victoria artwork ID'), ('p', 'http://www.wikidata.org/prop/direct/P4684')]
# [('pname', 'ESPN.com NFL player ID'), ('p', 'http://www.wikidata.org/prop/direct/P3686')]
# [('pname', 'DC Comics talent ID'), ('p', 'http://www.wikidata.org/prop/direct/P7951')]
# 2770

# %% [markdown]
# #### Comment
# Some properties that can highlight the country for which a politician works are:
#
# | IRI           | Description   | Role      |
# | -----------   | -----------   |-----------|
# | `wdt:P27`   | citizenship   | predicate |
# | `wdt:P39`     | position held   | predicate |
# | `wdt:P937`     | work location   | predicate |
# | `wdt:P945`     | allegiance   | predicate |
#
# Let's try to find the path from position held

# %%
#Let's print some psoition held nodes
queryString = """
SELECT DISTINCT ?sname ?oname ?obj
WHERE { 

# ?pol wdt:P106/wdt:P279{0,2} wd:Q82955 ;
     wdt:P39 ?obj .

#?p <http://schema.org/name> ?pname .
# ?pol <http://schema.org/name> ?sname .
OPTIONAL { ?obj <http://schema.org/name> ?oname . } .

}
LIMIT 50
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('sname', 'Emperor Taizu of Song'), ('oname', 'Emperor'), ('obj', 'http://www.wikidata.org/entity/Q39018')]
# [('sname', 'Emperor Taizu of Song'), ('oname', 'Emperor of China'), ('obj', 'http://www.wikidata.org/entity/Q268218')]
# [('sname', 'Patrick Buisson'), ('oname', 'vice president'), ('obj', 'http://www.wikidata.org/entity/Q42178')]
# [('sname', 'Patrick Buisson'), ('oname', 'general director'), ('obj', 'http://www.wikidata.org/entity/Q1048210')]
# [('sname', 'Mahapadma Nanda'), ('oname', 'Emperor'), ('obj', 'http://www.wikidata.org/entity/Q39018')]
# [('sname', 'Emperor Duzong of Song'), ('oname', 'crown prince'), ('obj', 'http://www.wikidata.org/entity/Q207293')]
# [('sname', 'Emperor Duzong of Song'), ('oname', 'Emperor of China'), ('obj', 'http://www.wikidata.org/entity/Q268218')]
# [('sname', 'Al-Mujahid Shirkuh'), ('oname', 'emir'), ('obj', 'http://www.wikidata.org/entity/Q166382')]
# [('sname', 'Bahramshah'), ('oname', 'emir'), ('obj', 'http://www.wikidata.org/entity/Q166382')]
# [('sname', 'Farrukh Shah'), ('oname', 'emir'), ('obj', 'http://www.wikidata.org/entity/Q166382')]
# [('sname', 'Muhammad ibn Shirkuh'), ('oname', 'emir'), ('obj', 'http://www.wikidata.org/entity/Q166382')]
# [('sname', 'Al-Muzaffar Umar'), ('oname', 'viceroy'), ('obj', 'http://www.wikidata.org/entity/Q244741')]
# [('sname', 'Al-Muzaffar Umar'), ('oname', 'Emir of Hama'), ('obj', 'http://www.wikidata.org/entity/Q104162055')]
# [('sname', 'Pasenadi'), ('oname', 'king'), ('obj', 'http://www.wikidata.org/entity/Q12097')]
# [('sname', 'Zoe Bettison'), ('oname', 'Member of the South Australian House of Assembly'), ('obj', 'http://www.wikidata.org/entity/Q18220900')]
# [('sname', 'Zoe Bettison'), ('oname', 'Minister for Multicultural Affairs'), ('obj', 'http://www.wikidata.org/entity/Q50390789')]
# [('sname', 'Zoe Bettison'), ('oname', 'Minister for Volunteers'), ('obj', 'http://www.wikidata.org/entity/Q50389144')]
# [('sname', 'Zoe Bettison'), ('oname', 'Minister for the Status of Women'), ('obj', 'http://www.wikidata.org/entity/Q50825407')]
# [('sname', 'Zoe Bettison'), ('oname', 'Minister for Ageing'), ('obj', 'http://www.wikidata.org/entity/Q50825411')]
# [('sname', 'Zoe Bettison'), ('oname', 'Minister for Youth'), ('obj', 'http://www.wikidata.org/entity/Q50866411')]
# [('sname', 'Zoe Bettison'), ('oname', "Minister for Veterans' Affairs"), ('obj', 'http://www.wikidata.org/entity/Q50807345')]
# [('sname', 'Zoe Bettison'), ('oname', 'Minister for Social Housing'), ('obj', 'http://www.wikidata.org/entity/Q50825403')]
# [('sname', 'Zoe Bettison'), ('oname', 'Minister for Communities and Social Inclusion'), ('obj', 'http://www.wikidata.org/entity/Q50867941')]
# [('sname', 'Ramon Coma i Casellas'), ('oname', 'Member of the Parliament of Catalonia'), ('obj', 'http://www.wikidata.org/entity/Q18714088')]
# [('sname', 'Ramon Coma i Casellas'), ('oname', 'mayor of Puig-reig'), ('obj', 'http://www.wikidata.org/entity/Q26691677')]
# [('sname', 'Mufasa'), ('oname', 'king'), ('obj', 'http://www.wikidata.org/entity/Q12097')]
# [('sname', 'Haibatullah Akhundzada'), ('oname', "Amir al-Mu'minin"), ('obj', 'http://www.wikidata.org/entity/Q2081829')]
# [('sname', 'René Bidal'), ('oname', 'General secretary of prefecture of Aveyron'), ('obj', 'http://www.wikidata.org/entity/Q75837872')]
# [('sname', 'René Bidal'), ('oname', 'High Commissioner of the Republic in French Polynesia'), ('obj', 'http://www.wikidata.org/entity/Q78146717')]
# [('sname', 'René Bidal'), ('oname', 'Prefect of Pyrénées-Orientales'), ('obj', 'http://www.wikidata.org/entity/Q28570372')]
# [('sname', 'René Bidal'), ('oname', 'Prefect of Hautes-Pyrénées'), ('obj', 'http://www.wikidata.org/entity/Q64451643')]
# [('sname', 'René Bidal'), ('oname', 'Prefect of Eure'), ('obj', 'http://www.wikidata.org/entity/Q64442983')]
# [('sname', 'René Bidal'), ('oname', 'Prefect of Maine-et-Loire'), ('obj', 'http://www.wikidata.org/entity/Q65314773')]
# [('sname', 'Stéphane Séjourné'), ('oname', 'member of the European Parliament'), ('obj', 'http://www.wikidata.org/entity/Q27169')]
# [('sname', 'Roman I of Moldavia'), ('oname', 'hospodar'), ('obj', 'http://www.wikidata.org/entity/Q1394172')]
# [('sname', 'Stefan Nemanja'), ('oname', 'Župan'), ('obj', 'http://www.wikidata.org/entity/Q720247')]
# [('sname', 'Rokujō'), ('oname', 'Emperor of Japan'), ('obj', 'http://www.wikidata.org/entity/Q208233')]
# [('sname', 'Takakura'), ('oname', 'Emperor of Japan'), ('obj', 'http://www.wikidata.org/entity/Q208233')]
# [('sname', 'Alexios II of Trebizond'), ('oname', 'Emperor of Trebizond'), ('obj', 'http://www.wikidata.org/entity/Q28150764')]
# [('sname', 'Nijō'), ('oname', 'Emperor of Japan'), ('obj', 'http://www.wikidata.org/entity/Q208233')]
# [('sname', 'Baydu'), ('oname', 'Khan'), ('obj', 'http://www.wikidata.org/entity/Q181888')]
# [('sname', 'Go-Kameyama'), ('oname', 'Emperor of Japan'), ('obj', 'http://www.wikidata.org/entity/Q208233')]
# [('sname', 'Alfonso Fróilaz'), ('oname', 'Monarch of the Kingdom of León'), ('obj', 'http://www.wikidata.org/entity/Q55502624')]
# [('sname', 'John George III of Saxony'), ('oname', 'Prince-Elector'), ('obj', 'http://www.wikidata.org/entity/Q22722')]
# [('sname', 'Rita Ottervik'), ('oname', 'mayor of Trondheim'), ('obj', 'http://www.wikidata.org/entity/Q56525898')]
# [('sname', 'Rita Ottervik'), ('oname', 'deputy member of the Parliament of Norway'), ('obj', 'http://www.wikidata.org/entity/Q16159375')]
# [('sname', 'Archidamus IV'), ('oname', 'king of Sparta'), ('obj', 'http://www.wikidata.org/entity/Q107905')]
# [('sname', 'Eudamidas I'), ('oname', 'king of Sparta'), ('obj', 'http://www.wikidata.org/entity/Q107905')]
# [('sname', 'Geoffrey II of Villehardouin'), ('oname', 'Prince of Achaea'), ('obj', 'http://www.wikidata.org/entity/Q42724549')]
# [('sname', 'Eudamidas II'), ('oname', 'king of Sparta'), ('obj', 'http://www.wikidata.org/entity/Q107905')]
# 50

# %% [markdown]
# #### Comment
# Let's try to see if some of this position held nodes have as outgoing relation "country" (wdt:P17) that connect them with the country in which they held that position

# %%
#Let's try what I saied in the previous comment tring to extract the Italian politicians
queryString = """
SELECT DISTINCT ?sname ?oname
WHERE { 

# ?pol wdt:P106/wdt:P279{0,2} wd:Q82955 ;
     wdt:P39 ?obj .
# ?obj wdt:P17 wd:Q38 .

#?cou <http://schema.org/name> ?cname .
# ?pol <http://schema.org/name> ?sname .
# ?obj <http://schema.org/name> ?oname .

}
LIMIT 50
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('sname', 'Henry II, Holy Roman Emperor'), ('oname', 'monarch of Italy')]
# [('sname', 'Frederick III, Holy Roman Emperor'), ('oname', 'monarch of Italy')]
# [('sname', 'James of Baux'), ('oname', 'Prince of Tarente')]
# [('sname', 'Francesco De Pasquale'), ('oname', 'mayor of Carrara')]
# [('sname', 'Mario Martone'), ('oname', 'president of the Province of Potenza')]
# [('sname', 'Salvatore Chiantia'), ('oname', 'mayor of a place in Italy')]
# [('sname', 'Giovanni Bernardini'), ('oname', 'mayor of a place in Italy')]
# [('sname', 'Rosa Stanisci'), ('oname', 'member of the Italian Senate')]
# [('sname', 'Rosa Stanisci'), ('oname', 'member of the Chamber of Deputies of the Italian Republic')]
# [('sname', 'Michelangelo Giusta'), ('oname', 'mayor of a place in Italy')]
# [('sname', 'Ludovico Sforza'), ('oname', 'duke of Milan')]
# [('sname', 'Filippo Maria Visconti'), ('oname', 'duke of Milan')]
# [('sname', 'Mario Beccaria'), ('oname', 'member of the Chamber of Deputies of the Italian Republic')]
# [('sname', 'Mario Beccaria'), ('oname', "mayor of Sant'Angelo Lodigiano")]
# [('sname', 'Juan Rena'), ('oname', 'bishop of Alghero')]
# [('sname', 'Roberto Rampi'), ('oname', 'member of the Chamber of Deputies of the Italian Republic')]
# [('sname', 'Roberto Rampi'), ('oname', 'member of the Italian Senate')]
# [('sname', 'Sandro Delmastro delle Vedove'), ('oname', 'member of the Chamber of Deputies of the Italian Republic')]
# [('sname', 'Andrea Delmastro Delle Vedove'), ('oname', 'member of the Chamber of Deputies of the Italian Republic')]
# [('sname', 'Orazio Santagati'), ('oname', 'member of the Chamber of Deputies of the Italian Republic')]
# [('sname', 'Guido Guidesi'), ('oname', 'member of the Chamber of Deputies of the Italian Republic')]
# [('sname', 'Gianluca Rossi'), ('oname', 'member of the Italian Senate')]
# [('sname', 'Gianna Malisani'), ('oname', 'member of the Chamber of Deputies of the Italian Republic')]
# [('sname', 'Gessica Rostellato'), ('oname', 'member of the Chamber of Deputies of the Italian Republic')]
# [('sname', 'Gianni Melilla'), ('oname', 'member of the Chamber of Deputies of the Italian Republic')]
# [('sname', 'Giovanni Carbonella'), ('oname', 'member of the Chamber of Deputies of the Italian Republic')]
# [('sname', 'Filippo Sensi'), ('oname', 'member of the Chamber of Deputies of the Italian Republic')]
# [('sname', 'Giovanni Barozzino'), ('oname', 'member of the Italian Senate')]
# [('sname', 'Valeria Cardinali'), ('oname', 'member of the Italian Senate')]
# [('sname', 'Gianluca Castaldi'), ('oname', 'member of the Italian Senate')]
# [('sname', 'Luigi Gaetti'), ('oname', 'member of the Italian Senate')]
# [('sname', 'Pietro Iurlaro'), ('oname', 'member of the Italian Senate')]
# [('sname', 'Bruno Mancuso'), ('oname', 'member of the Italian Senate')]
# [('sname', 'Massimo Cassano'), ('oname', 'member of the Italian Senate')]
# [('sname', 'Enrico Piccinelli'), ('oname', 'member of the Italian Senate')]
# [('sname', 'Giovanni Piccoli'), ('oname', 'member of the Italian Senate')]
# [('sname', 'Antonio Scavone'), ('oname', 'member of the Italian Senate')]
# [('sname', 'Antonio Scavone'), ('oname', 'member of the Chamber of Deputies of the Italian Republic')]
# [('sname', 'Antonio Giuseppe Maria Verro'), ('oname', 'member of the Chamber of Deputies of the Italian Republic')]
# [('sname', 'Antonio Giuseppe Maria Verro'), ('oname', 'member of the Italian Senate')]
# [('sname', 'Federigo De Larderel'), ('oname', 'mayor of Livorno')]
# [('sname', 'Franco Roccon'), ('oname', 'mayor of a place in Italy')]
# [('sname', 'Vittorino Pavan'), ('oname', 'mayor of Treviso')]
# [('sname', 'Pietro Fabris'), ('oname', 'member of the Italian Senate')]
# [('sname', 'Adolfo Manis'), ('oname', 'member of the Italian Senate')]
# [('sname', 'Giuseppe Russo'), ('oname', 'member of the Italian Senate')]
# [('sname', 'Giuseppe Russo'), ('oname', 'mayor of a place in Italy')]
# [('sname', 'Giovanni Mosca'), ('oname', 'member of the Chamber of Deputies of the Italian Republic')]
# [('sname', 'Ezio Anesi'), ('oname', 'member of the Italian Senate')]
# [('sname', 'Ezio Anesi'), ('oname', 'mayor of a place in Italy')]
# 50

# %% [markdown]
# #### Comment
# And so the BGP to retrieve for each E.U. country its politicians is:
#
# ```
# ?pol wdt:P106/wdt:P279{0,2} wd:Q82955 ;
#      wdt:P39 ?pos .
# ?pos wdt:P17 ?cou .
# ?cou wdt:P463 wd:Q458 .
# ```

# %%
# Let's see if it works in an example query (result list limited to 25) 
queryString = """
SELECT DISTINCT ?country ?sname ?posname
WHERE { 

# ?pol wdt:P106/wdt:P279{0,2} wd:Q82955 ;
     wdt:P39 ?pos .
# ?pos wdt:P17 ?cou .
# ?cou wdt:P463 wd:Q458 .

# ?cou <http://schema.org/name> ?country .
# ?pol <http://schema.org/name> ?sname .
# ?pos <http://schema.org/name> ?posname .

}
ORDER BY ASC (?country)
LIMIT 25
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('country', 'Austria'), ('sname', 'Gernot Rumpold'), ('posname', 'member of the Austrian federal council')]
# [('country', 'Austria'), ('sname', 'Sebastian Hutstocker'), ('posname', 'mayor of Vienna')]
# [('country', 'Austria'), ('sname', 'Josef Georg Hörl'), ('posname', 'mayor of Vienna')]
# [('country', 'Austria'), ('sname', 'Gustav Zeller'), ('posname', 'mayor of Salzburg')]
# [('country', 'Austria'), ('sname', 'Karl Bregartner'), ('posname', 'member of the National Council of Austria')]
# [('country', 'Austria'), ('sname', 'Gerald Hauser'), ('posname', 'member of the National Council of Austria')]
# [('country', 'Austria'), ('sname', 'Alois Spängler'), ('posname', 'mayor of Salzburg')]
# [('country', 'Austria'), ('sname', 'Johann Singer'), ('posname', 'member of the National Council of Austria')]
# [('country', 'Austria'), ('sname', 'Sigmund Haffner der Ältere'), ('posname', 'mayor of Salzburg')]
# [('country', 'Austria'), ('sname', 'Thomas Drozda'), ('posname', 'member of the National Council of Austria')]
# [('country', 'Austria'), ('sname', 'Thomas Drozda'), ('posname', 'Chancellery minister')]
# [('country', 'Austria'), ('sname', 'Josef Heinzl'), ('posname', 'Member of the Landtag of Lower Austria')]
# [('country', 'Austria'), ('sname', 'Anton Seidel'), ('posname', 'member of the National Council of Austria')]
# [('country', 'Austria'), ('sname', 'Josef Goll'), ('posname', 'member of the National Council of Austria')]
# [('country', 'Austria'), ('sname', 'Simon Hofbauer'), ('posname', 'Member of the Landtag of Salzburg')]
# [('country', 'Austria'), ('sname', 'Karl Fisslthaler'), ('posname', 'member of the National Council of Austria')]
# [('country', 'Austria'), ('sname', 'Ludwig Wutschel'), ('posname', 'member of the National Council of Austria')]
# [('country', 'Austria'), ('sname', 'Ludwig Wutschel'), ('posname', 'member of the regional parliament of Vienna')]
# [('country', 'Austria'), ('sname', 'Josef Wille'), ('posname', 'member of the National Council of Austria')]
# [('country', 'Austria'), ('sname', 'Josef Siegele'), ('posname', 'member of the National Council of Austria')]
# [('country', 'Austria'), ('sname', 'Johann Roitinger'), ('posname', 'member of the National Council of Austria')]
# [('country', 'Austria'), ('sname', 'Heinrich Pichler'), ('posname', 'member of the National Council of Austria')]
# [('country', 'Austria'), ('sname', 'Johann Kreilmeir'), ('posname', 'member of the National Council of Austria')]
# [('country', 'Austria'), ('sname', 'Johann Kreilmeir'), ('posname', 'member of the Austrian federal council')]
# [('country', 'Austria'), ('sname', 'Franz Huber'), ('posname', 'member of the National Council of Austria')]
# 25

# %% [markdown]
# #### Comment
# Ok the BGP retrieves the information requested in the task

# %% [markdown]
# ## Task 2
# 2. Identify the BGP for obtaining other occupations and properties of politicians

# %%
#Let's print for every politicians his/her other occupation and properties
queryString = """
SELECT DISTINCT ?politician ?property ?oname
WHERE { 

{
# ?pol wdt:P106/wdt:P279{0,2} wd:Q82955 ;
     # ?p ?obj .

FILTER(?obj != wd:Q82955 && ?p = wdt:P106) .

}UNION{
# ?pol wdt:P106/wdt:P279{0,2} wd:Q82955 ;
     # ?p ?obj .
     
FILTER(?obj != wd:Q82955) .
}

# ?p <http://schema.org/name> ?property .
# ?pol <http://schema.org/name> ?politician .
OPTIONAL { ?obj <http://schema.org/name> ?oname . } .

}
#GROUP BY ?politician ?property
ORDER BY ASC (?politician)
LIMIT 25
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('politician', '"Big" Donnie MacLeod'), ('property', 'member of political party'), ('oname', 'Progressive Conservative Association of Nova Scotia')]
# [('politician', '"Big" Donnie MacLeod'), ('property', 'languages spoken, written or signed'), ('oname', 'English')]
# [('politician', '"Big" Donnie MacLeod'), ('property', 'place of birth'), ('oname', 'Nova Scotia')]
# [('politician', '"Big" Donnie MacLeod'), ('property', 'sex or gender'), ('oname', 'male')]
# [('politician', '"Big" Donnie MacLeod'), ('property', 'country of citizenship'), ('oname', 'Canada')]
# [('politician', '"Big" Donnie MacLeod'), ('property', 'instance of'), ('oname', 'human')]
# [('politician', '"Big" Donnie MacLeod'), ('property', 'family name'), ('oname', 'MacLeod')]
# [('politician', '"Big" Donnie MacLeod'), ('property', 'birth name')]
# [('politician', '"Big" Donnie MacLeod'), ('property', 'date of birth')]
# [('politician', '"Big" Donnie MacLeod'), ('property', 'date of death')]
# [('politician', '"Big" Donnie MacLeod'), ('property', 'Freebase ID')]
# [('politician', '"Big" Donnie MacLeod'), ('property', 'given name'), ('oname', 'Archie')]
# [('politician', '"Big" Donnie MacLeod'), ('property', 'given name'), ('oname', 'Donald')]
# [('politician', "'Abd Allah II ibn 'Ali 'Abd ash-Shakur"), ('property', 'sex or gender'), ('oname', 'male')]
# [('politician', "'Abd Allah II ibn 'Ali 'Abd ash-Shakur"), ('property', 'father'), ('oname', "Muhammad ibn 'Ali 'Abd ash-Shakur")]
# [('politician', "'Abd Allah II ibn 'Ali 'Abd ash-Shakur"), ('property', 'instance of'), ('oname', 'human')]
# [('politician', "'Abd Allah II ibn 'Ali 'Abd ash-Shakur"), ('property', 'position held'), ('oname', 'emir')]
# [('politician', "'Abd Allah II ibn 'Ali 'Abd ash-Shakur"), ('property', 'image')]
# [('politician', "'Abd Allah II ibn 'Ali 'Abd ash-Shakur"), ('property', 'date of death')]
# [('politician', "'Abd Allah II ibn 'Ali 'Abd ash-Shakur"), ('property', 'Freebase ID')]
# [('politician', "'Abd al-'Aziz ibn Marwan"), ('property', 'instance of'), ('oname', 'human')]
# [('politician', "'Abd al-Ilah"), ('property', 'occupation'), ('oname', 'military personnel')]
# [('politician', "'Abd al-Ilah"), ('property', 'place of burial'), ('oname', 'Al Khaisaran cemetery')]
# [('politician', "'Abd al-Ilah"), ('property', 'manner of death'), ('oname', 'homicide')]
# [('politician', "'Abd al-Ilah"), ('property', 'religion'), ('oname', 'Islam')]
# 25

# %% [markdown]
# #### Comment
# The BGP to find other occupations and properties of a politician is:
#
# ```
# {
# ?pol wdt:P106/wdt:P279{0,2} wd:Q82955 ;
#      ?p ?obj .
#
# FILTER(?obj != wd:Q82955 && ?p = wdt:P106) .
#
# }UNION{
# ?pol wdt:P106/wdt:P279{0,2} wd:Q82955 ;
#      ?p ?obj .
#
# FILTER(?obj != wd:Q82955) .
# }
# ```
# I'm using the UNION only for better point out the to part of the question in the solution of the task, the same thing can be done also without using this construct.
#
# As we can see from the results we retrieve the other properties and the other occupation different from politician.
#
# EXAMPLE:
#
# [('politician', "'Abd al-Ilah"), ('property', 'occupation'), ('oname', 'military personnel')]
# [('politician', "'Abd al-Ilah"), ('property', 'place of burial'), ('oname', 'Al Khaisaran cemetery')]
# [('politician', "'Abd al-Ilah"), ('property', 'manner of death'), ('oname', 'homicide')]
# [('politician', "'Abd al-Ilah"), ('property', 'religion'), ('oname', 'Islam')]

# %% [markdown]
# ## Task 3
# 3. How many politicians are recorder for each E.U. country?

# %% [markdown]
# #### Comment
# I don't know what do you mean with "how many politicians ARE RECORDER...", I presume that there is a typing error and so the right phrase is "how many politicians ARE RECORDED..."
# For this reason I'm going to solve the task in this second way.

# %%
# Let's count for each E.U. country the number of politician in the DB, the count considers both the living ones and the dead ones 
queryString = """
SELECT DISTINCT ?country (COUNT(DISTINCT ?pol) AS ?numpol)
WHERE { 

# ?pol wdt:P106/wdt:P279{0,2} wd:Q82955 ;
     wdt:P39 ?pos .
# ?pos wdt:P17 ?cou .
# ?cou wdt:P463 wd:Q458 .

# ?cou <http://schema.org/name> ?country .

}
GROUP BY ?country
ORDER BY ASC (?country)
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('country', 'Austria'), ('numpol', '4693')]
# [('country', 'Belgium'), ('numpol', '5661')]
# [('country', 'Bulgaria'), ('numpol', '549')]
# [('country', 'Croatia'), ('numpol', '346')]
# [('country', 'Cyprus'), ('numpol', '494')]
# [('country', 'Czech Republic'), ('numpol', '1684')]
# [('country', 'Denmark'), ('numpol', '329')]
# [('country', 'Estonia'), ('numpol', '1050')]
# [('country', 'Finland'), ('numpol', '16175')]
# [('country', 'France'), ('numpol', '72983')]
# [('country', 'Germany'), ('numpol', '16951')]
# [('country', 'Greece'), ('numpol', '3814')]
# [('country', 'Hungary'), ('numpol', '3137')]
# [('country', 'Ireland'), ('numpol', '1981')]
# [('country', 'Italy'), ('numpol', '9727')]
# [('country', 'Kingdom of the Netherlands'), ('numpol', '3698')]
# [('country', 'Latvia'), ('numpol', '740')]
# [('country', 'Lithuania'), ('numpol', '787')]
# [('country', 'Luxembourg'), ('numpol', '989')]
# [('country', 'Malta'), ('numpol', '112')]
# [('country', 'Poland'), ('numpol', '2647')]
# [('country', 'Portugal'), ('numpol', '1169')]
# [('country', 'Romania'), ('numpol', '8132')]
# [('country', 'Slovakia'), ('numpol', '203')]
# [('country', 'Slovenia'), ('numpol', '141')]
# [('country', 'Spain'), ('numpol', '17183')]
# [('country', 'Sweden'), ('numpol', '5433')]
# [('country', 'United Kingdom'), ('numpol', '9665')]
# 28

# %% [markdown]
# #### Comment
# As you can see I've counted the number of distinct politicians for each E.U. country.
# Even in this case "United Kingdom" is considered inside E.U. but this is no longer the case.

# %% [markdown]
# ## Task 4
# 4. Are there politicians with double citizenship?

# %%
#Let's return the number of distinct citizenship for each politician with two or more of them
queryString = """
SELECT ?polname (COUNT(DISTINCT ?c) AS ?numcity)
WHERE { 

# ?pol wdt:P106/wdt:P279{0,2} wd:Q82955 ;
     wdt:P39 ?pos ;
     # ?city ?c .
# ?pos wdt:P17 ?cou .

FILTER(?city = wdt:P27)

# ?pol <http://schema.org/name> ?polname .

}
GROUP BY ?polname
HAVING((COUNT(DISTINCT ?c)) > 1)
ORDER BY ASC (?polname)
LIMIT 25
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('polname', 'A V Swamy'), ('numcity', '2')]
# [('polname', 'A. A. Nikonov'), ('numcity', '2')]
# [('polname', 'A. C. Shanmughadas'), ('numcity', '3')]
# [('polname', 'A. Charles'), ('numcity', '3')]
# [('polname', 'A. Chatterjee'), ('numcity', '2')]
# [('polname', 'A. Dharam Dass'), ('numcity', '3')]
# [('polname', 'A. F. M. Ahsanuddin Chowdhury'), ('numcity', '5')]
# [('polname', 'A. G.  Savinykh'), ('numcity', '3')]
# [('polname', 'A. G. Kulkarni'), ('numcity', '3')]
# [('polname', 'A. G. Subburaman'), ('numcity', '2')]
# [('polname', 'A. J. John, Anaparambil'), ('numcity', '3')]
# [('polname', 'A. K. A. Abdul Samad'), ('numcity', '3')]
# [('polname', 'A. K. Bose'), ('numcity', '2')]
# [('polname', 'A. K. Faezul Huq'), ('numcity', '3')]
# [('polname', 'A. K. Gopalan'), ('numcity', '3')]
# [('polname', 'A. K. Roy'), ('numcity', '2')]
# [('polname', 'A. Karunakara Menon'), ('numcity', '3')]
# [('polname', 'A. M. Paraman'), ('numcity', '3')]
# [('polname', 'A. M. Zahiruddin Khan'), ('numcity', '3')]
# [('polname', 'A. Malarmannan'), ('numcity', '2')]
# [('polname', 'A. Nesamony'), ('numcity', '3')]
# [('polname', 'A. P. J. Abdul Kalam'), ('numcity', '2')]
# [('polname', 'A. P. Shanmugasundara Goundar'), ('numcity', '3')]
# [('polname', 'A. Q. M. Badruddoza Chowdhury'), ('numcity', '3')]
# [('polname', 'A. R. Antulay'), ('numcity', '3')]
# 25

# %%
# Same result as the previous query but using another writing design
queryString = """

SELECT DISTINCT ?polname ?num ?p WHERE {

# ?p wdt:P106/wdt:P279{0,2} wd:Q82955 ;
     wdt:P39 ?pos ;
     wdt:P27 ?c .
# ?pos wdt:P17 ?cou .

FILTER(?p = ?pol && ?num > 1)
{
    SELECT ?pol (COUNT(DISTINCT ?nat) AS ?num) WHERE { 

        # ?pol wdt:P106/wdt:P279{0,2} wd:Q82955 ;
             wdt:P39 ?pos1 ;
             wdt:P27 ?nat .
        # ?pos1 wdt:P17 ?cou1 .
            
    }
    GROUP BY ?pol
}

# ?p <http://schema.org/name> ?polname .
}
ORDER BY ASC (?polname)
LIMIT 25
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('polname', 'A V Swamy'), ('num', '2'), ('p', 'http://www.wikidata.org/entity/Q18611756')]
# [('polname', 'A. A. Nikonov'), ('num', '2'), ('p', 'http://www.wikidata.org/entity/Q4321109')]
# [('polname', 'A. C. Shanmughadas'), ('num', '3'), ('p', 'http://www.wikidata.org/entity/Q15993493')]
# [('polname', 'A. Charles'), ('num', '3'), ('p', 'http://www.wikidata.org/entity/Q20047087')]
# [('polname', 'A. Chatterjee'), ('num', '2'), ('p', 'http://www.wikidata.org/entity/Q106314804')]
# [('polname', 'A. Dharam Dass'), ('num', '3'), ('p', 'http://www.wikidata.org/entity/Q61943802')]
# [('polname', 'A. F. M. Ahsanuddin Chowdhury'), ('num', '5'), ('p', 'http://www.wikidata.org/entity/Q278218')]
# [('polname', 'A. G.  Savinykh'), ('num', '3'), ('p', 'http://www.wikidata.org/entity/Q4404043')]
# [('polname', 'A. G. Kulkarni'), ('num', '3'), ('p', 'http://www.wikidata.org/entity/Q16012824')]
# [('polname', 'A. G. Subburaman'), ('num', '2'), ('p', 'http://www.wikidata.org/entity/Q4647807')]
# [('polname', 'A. J. John, Anaparambil'), ('num', '3'), ('p', 'http://www.wikidata.org/entity/Q4647934')]
# [('polname', 'A. K. A. Abdul Samad'), ('num', '3'), ('p', 'http://www.wikidata.org/entity/Q3534002')]
# [('polname', 'A. K. Bose'), ('num', '2'), ('p', 'http://www.wikidata.org/entity/Q4648018')]
# [('polname', 'A. K. Faezul Huq'), ('num', '3'), ('p', 'http://www.wikidata.org/entity/Q4648023')]
# [('polname', 'A. K. Gopalan'), ('num', '3'), ('p', 'http://www.wikidata.org/entity/Q3595831')]
# [('polname', 'A. K. Roy'), ('num', '2'), ('p', 'http://www.wikidata.org/entity/Q24851623')]
# [('polname', 'A. Karunakara Menon'), ('num', '3'), ('p', 'http://www.wikidata.org/entity/Q61941484')]
# [('polname', 'A. M. Paraman'), ('num', '3'), ('p', 'http://www.wikidata.org/entity/Q4647246')]
# [('polname', 'A. M. Zahiruddin Khan'), ('num', '3'), ('p', 'http://www.wikidata.org/entity/Q4648163')]
# [('polname', 'A. Malarmannan'), ('num', '2'), ('p', 'http://www.wikidata.org/entity/Q59113972')]
# [('polname', 'A. Nesamony'), ('num', '3'), ('p', 'http://www.wikidata.org/entity/Q4648214')]
# [('polname', 'A. P. J. Abdul Kalam'), ('num', '2'), ('p', 'http://www.wikidata.org/entity/Q9513')]
# [('polname', 'A. P. Shanmugasundara Goundar'), ('num', '3'), ('p', 'http://www.wikidata.org/entity/Q4648236')]
# [('polname', 'A. Q. M. Badruddoza Chowdhury'), ('num', '3'), ('p', 'http://www.wikidata.org/entity/Q278403')]
# [('polname', 'A. R. Antulay'), ('num', '3'), ('p', 'http://www.wikidata.org/entity/Q3595206')]
# 25

# %% [markdown]
# #### Comment
# Let's check if the results are correct

# %%
queryString = """
SELECT ?polname ?citizenship WHERE { 

# ?p wdt:P27 ?nat .

FILTER (?p = wd:Q18611756) .

# ?p <http://schema.org/name> ?polname .
# ?nat <http://schema.org/name> ?citizenship .

}
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('polname', 'A V Swamy'), ('citizenship', 'Dominion of India')]
# [('polname', 'A V Swamy'), ('citizenship', 'India')]
# 2

# %% [markdown]
# #### Comment
# The results are correct so I can say that some politicians have double citizenship

# %% [markdown]
# ## Task 5
# 5. Analyze the number of politicians in each country by occupation, for instance

# %% [markdown]
# ### Task 5.1
# 5.1 What are the top-3 occupations for a politician in Italy and France?

# %%
# Top-3 occupations for a politician in Italy
queryString = """
SELECT DISTINCT ?oname (COUNT(DISTINCT ?pol) AS ?num)
WHERE { 

# ?pol wdt:P106/wdt:P279{0,2} wd:Q82955 ;
     # ?p ?occ ;
     wdt:P39 ?pos .
# ?pos wdt:P17 ?cou .

FILTER(?occ != wd:Q82955 && ?p = wdt:P106) .
FILTER(?cou = wd:Q38) .

# ?occ <http://schema.org/name> ?oname .

}
GROUP BY ?oname
ORDER BY DESC (?num)
LIMIT 3
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('oname', 'lawyer'), ('num', '593')]
# [('oname', 'journalist'), ('num', '507')]
# [('oname', 'writer'), ('num', '189')]
# 3

# %%
# Let's print the URIs for the E.U. countries to found the France ones
queryString = """
SELECT DISTINCT ?country ?cou
WHERE { 

# ?pol wdt:P106/wdt:P279{0,2} wd:Q82955 ;
     wdt:P39 ?pos .
# ?pos wdt:P17 ?cou .
# ?cou wdt:P463 wd:Q458 .

# ?cou <http://schema.org/name> ?country .
# ?pol <http://schema.org/name> ?sname .
# ?pos <http://schema.org/name> ?posname .

}
ORDER BY ASC (?country)
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('country', 'Austria'), ('cou', 'http://www.wikidata.org/entity/Q40')]
# [('country', 'Belgium'), ('cou', 'http://www.wikidata.org/entity/Q31')]
# [('country', 'Bulgaria'), ('cou', 'http://www.wikidata.org/entity/Q219')]
# [('country', 'Croatia'), ('cou', 'http://www.wikidata.org/entity/Q224')]
# [('country', 'Cyprus'), ('cou', 'http://www.wikidata.org/entity/Q229')]
# [('country', 'Czech Republic'), ('cou', 'http://www.wikidata.org/entity/Q213')]
# [('country', 'Denmark'), ('cou', 'http://www.wikidata.org/entity/Q35')]
# [('country', 'Estonia'), ('cou', 'http://www.wikidata.org/entity/Q191')]
# [('country', 'Finland'), ('cou', 'http://www.wikidata.org/entity/Q33')]
# [('country', 'France'), ('cou', 'http://www.wikidata.org/entity/Q142')]
# [('country', 'Germany'), ('cou', 'http://www.wikidata.org/entity/Q183')]
# [('country', 'Greece'), ('cou', 'http://www.wikidata.org/entity/Q41')]
# [('country', 'Hungary'), ('cou', 'http://www.wikidata.org/entity/Q28')]
# [('country', 'Ireland'), ('cou', 'http://www.wikidata.org/entity/Q27')]
# [('country', 'Italy'), ('cou', 'http://www.wikidata.org/entity/Q38')]
# [('country', 'Kingdom of the Netherlands'), ('cou', 'http://www.wikidata.org/entity/Q29999')]
# [('country', 'Latvia'), ('cou', 'http://www.wikidata.org/entity/Q211')]
# [('country', 'Lithuania'), ('cou', 'http://www.wikidata.org/entity/Q37')]
# [('country', 'Luxembourg'), ('cou', 'http://www.wikidata.org/entity/Q32')]
# [('country', 'Malta'), ('cou', 'http://www.wikidata.org/entity/Q233')]
# [('country', 'Poland'), ('cou', 'http://www.wikidata.org/entity/Q36')]
# [('country', 'Portugal'), ('cou', 'http://www.wikidata.org/entity/Q45')]
# [('country', 'Romania'), ('cou', 'http://www.wikidata.org/entity/Q218')]
# [('country', 'Slovakia'), ('cou', 'http://www.wikidata.org/entity/Q214')]
# [('country', 'Slovenia'), ('cou', 'http://www.wikidata.org/entity/Q215')]
# [('country', 'Spain'), ('cou', 'http://www.wikidata.org/entity/Q29')]
# [('country', 'Sweden'), ('cou', 'http://www.wikidata.org/entity/Q34')]
# [('country', 'United Kingdom'), ('cou', 'http://www.wikidata.org/entity/Q145')]
# 28

# %% [markdown]
# #### Comment
# We found:
#
# | IRI           | Description   | Role      |
# | -----------   | -----------   |-----------|
# | `wd:Q142`     | European Union   | node |

# %%
# Top-3 occupations for a politician in France
queryString = """
SELECT DISTINCT ?oname (COUNT(DISTINCT ?pol) AS ?num)
WHERE { 

# ?pol wdt:P106/wdt:P279{0,2} wd:Q82955 ;
     # ?p ?occ ;
     wdt:P39 ?pos .
# ?pos wdt:P17 ?cou .

FILTER(?occ != wd:Q82955 && ?p = wdt:P106) .
FILTER(?cou = wd:Q142) .

# ?occ <http://schema.org/name> ?oname .

}
GROUP BY ?oname
ORDER BY DESC (?num)
LIMIT 3
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('oname', 'pensioner'), ('num', '14285')]
# [('oname', 'anciens cadres'), ('num', '5433')]
# [('oname', 'farm operator'), ('num', '4812')]
# 3

# %% [markdown]
# #### Comment
# Let's check the results

# %%
# Let's print the URIs of the top 3 occupations for French politician
queryString = """
SELECT DISTINCT ?oname (COUNT(DISTINCT ?pol) AS ?num) ?occ
WHERE { 

# ?pol wdt:P106/wdt:P279{0,2} wd:Q82955 ;
     # ?p ?occ ;
     wdt:P39 ?pos .
# ?pos wdt:P17 ?cou .

FILTER(?occ != wd:Q82955 && ?p = wdt:P106) .
FILTER(?cou = wd:Q142) .

# ?occ <http://schema.org/name> ?oname .

}
GROUP BY ?occ ?oname
ORDER BY DESC (?num)
LIMIT 3
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('oname', 'pensioner'), ('num', '14285'), ('occ', 'http://www.wikidata.org/entity/Q1749879')]
# [('oname', 'anciens cadres'), ('num', '5433'), ('occ', 'http://www.wikidata.org/entity/Q97768274')]
# [('oname', 'farm operator'), ('num', '4812'), ('occ', 'http://www.wikidata.org/entity/Q3062119')]
# 3

# %%
#Let's print the French "farm operator" politician
queryString = """
SELECT COUNT(DISTINCT ?pol) 
WHERE { 

# ?pol wdt:P106/wdt:P279{0,2} wd:Q82955 ;
     # ?p ?occ ;
     wdt:P39 ?pos .
# ?pos wdt:P17 ?cou .

FILTER(?p = wdt:P106 && ?occ = wd:Q3062119) .
FILTER(?cou = wd:Q142) .

# ?occ <http://schema.org/name> ?oname .

}
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('callret-0', '4812')]
# 1

# %% [markdown]
# #### Comment
# After the check we see that the results are correct and so we can say that we have discovered the top-3 occupations for the Italian and French politician.

# %% [markdown]
# ### Task 5.2
# 5.2 What if you consider only politicians for which we don't have a date of death?

# %% [markdown]
# #### Comment
# I suppose that this task intend to reply the previous results but with this additional condition.
# So the results obtained for this task are taking into account only the politician still alive and the ones that have not their date of death saved.
#
# From the initial tasks we discovered that
#
# | IRI           | Description   | Role      |
# | -----------   | -----------   |-----------|
# | `wdt:P570`   | date of death   | predicate |

# %%
# Top-3 occupations for a politician in Italy without "date of death" relation
queryString = """
SELECT DISTINCT ?oname (COUNT(DISTINCT ?pol) AS ?num)
WHERE { 

# ?pol wdt:P106/wdt:P279{0,2} wd:Q82955 ;
     # ?p ?occ ;
     wdt:P39 ?pos .
# ?pos wdt:P17 ?cou .

FILTER(?occ != wd:Q82955 && ?p = wdt:P106) .
FILTER(?cou = wd:Q38) .
FILTER NOT EXISTS { ?pol wdt:P570 ?dd . } .

# ?p <http://schema.org/name> ?property .
# ?occ <http://schema.org/name> ?oname .

}
GROUP BY ?oname
ORDER BY DESC (?num)
LIMIT 3
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('oname', 'journalist'), ('num', '236')]
# [('oname', 'lawyer'), ('num', '214')]
# [('oname', 'entrepreneur'), ('num', '90')]
# 3

# %%
# Top-3 occupations for a politician in Italy without "date of death" relation
queryString = """
SELECT DISTINCT ?oname (COUNT(DISTINCT ?pol) AS ?num)
WHERE { 

# ?pol wdt:P106/wdt:P279{0,2} wd:Q82955 ;
     # ?p ?occ ;
     wdt:P39 ?pos .
# ?pos wdt:P17 ?cou .

FILTER(?occ != wd:Q82955 && ?p = wdt:P106) .
FILTER(?cou = wd:Q142) .
FILTER NOT EXISTS { ?pol wdt:P570 ?dd . } .

# ?p <http://schema.org/name> ?property .
# ?occ <http://schema.org/name> ?oname .

}
GROUP BY ?oname
ORDER BY DESC (?num)
LIMIT 3
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('oname', 'pensioner'), ('num', '14176')]
# [('oname', 'anciens cadres'), ('num', '5433')]
# [('oname', 'farm operator'), ('num', '4799')]
# 3

# %% [markdown]
# #### Comment
# For the Italian politicians we see from the difference between the results of this and the previous task that, more or less, a half of them have their "date of death" recorded, instead for the French ones the high majority doesn't have the "date of death".
# Mayybe this behaviour is due to the differences in the total number of the politicians between the two countries.

# %% [markdown]
# ### Task 5.3
# 5.3 Which politicians had a spouse that was also a politician? How many in each country?

# %% [markdown]
# #### Comment
# I'm going to consider only Italian and French politicians, like in the previous tasks, in answering the task.
#
# We have:
#
# | IRI           | Description   | Role      |
# | -----------   | -----------   |-----------|
# | `wdt:P26`     | spouse   | predicate |

# %%
# Let's print the Italian and French politicians which had a spouse that was also a politician
queryString = """
SELECT DISTINCT ?politician ?country ?spouse
WHERE { 

# ?pol wdt:P106/wdt:P279{0,2} wd:Q82955 ;
     wdt:P26 ?sp ;
     wdt:P39 ?pos .
# ?pos wdt:P17 ?cou .
# ?sp wdt:P106/wdt:P279{0,2} wd:Q82955 ;
    wdt:P39 ?pos1 .
# ?pos1 wdt:P17 ?cou1 .

FILTER(?cou = wd:Q142 || ?cou = wd:Q38) .

# ?pol <http://schema.org/name> ?politician .
# ?sp <http://schema.org/name> ?spouse .
# ?cou <http://schema.org/name> ?country .

}
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('politician', 'Yvonne de Gaulle'), ('country', 'France'), ('spouse', 'Charles de Gaulle')]
# [('politician', 'Cécilia Attias'), ('country', 'France'), ('spouse', 'Nicolas Sarkozy')]
# [('politician', 'Bernadette Chirac'), ('country', 'France'), ('spouse', 'Jacques Chirac')]
# [('politician', "Anne-Aymone Giscard d'Estaing"), ('country', 'France'), ('spouse', "Valéry Giscard d'Estaing")]
# [('politician', 'Boris Vallaud'), ('country', 'France'), ('spouse', 'Najat Vallaud-Belkacem')]
# [('politician', 'Aurore Bergé'), ('country', 'France'), ('spouse', 'Nicolas Bays')]
# [('politician', 'Girolamo Riario'), ('country', 'Italy'), ('spouse', 'Caterina Sforza')]
# [('politician', 'Caterina Sforza'), ('country', 'Italy'), ('spouse', 'Girolamo Riario')]
# [('politician', "Marie de' Medici"), ('country', 'France'), ('spouse', 'Henry IV of France')]
# [('politician', 'Marie-Claude Bompard'), ('country', 'France'), ('spouse', 'Jacques Bompard')]
# [('politician', 'Mara Carfagna'), ('country', 'Italy'), ('spouse', 'Alessandro Ruben')]
# [('politician', 'Gabriel Péri'), ('country', 'France'), ('spouse', 'Mathilde Gabriel-Péri')]
# [('politician', 'Jacques Bompard'), ('country', 'France'), ('spouse', 'Marie-Claude Bompard')]
# [('politician', 'Pierre Viénot'), ('country', 'France'), ('spouse', 'Andrée Viénot')]
# [('politician', 'Suzanne Schreiber'), ('country', 'France'), ('spouse', 'Robert Servan-Schreiber')]
# [('politician', 'Ibrahim Dindar'), ('country', 'France'), ('spouse', 'Nassimah Dindar')]
# [('politician', 'Pierre Villon'), ('country', 'France'), ('spouse', 'Marie-Claude Vaillant-Couturier')]
# [('politician', 'Paul Vaillant-Couturier'), ('country', 'France'), ('spouse', 'Marie-Claude Vaillant-Couturier')]
# [('politician', 'Robert Servan-Schreiber'), ('country', 'France'), ('spouse', 'Suzanne Schreiber')]
# [('politician', 'Nassimah Dindar'), ('country', 'France'), ('spouse', 'Ibrahim Dindar')]
# [('politician', 'Charles de Morny, Duke of Morny'), ('country', 'France'), ('spouse', "Sof'ja Sergeevna Trubeckaja")]
# [('politician', 'Claude Pompidou'), ('country', 'France'), ('spouse', 'Georges Pompidou')]
# [('politician', 'Jacques Chirac'), ('country', 'France'), ('spouse', 'Bernadette Chirac')]
# [('politician', 'Georges Pompidou'), ('country', 'France'), ('spouse', 'Claude Pompidou')]
# [('politician', 'Catherine Mégret'), ('country', 'France'), ('spouse', 'Bruno Mégret')]
# [('politician', 'Jeannette Vermeersch'), ('country', 'France'), ('spouse', 'Maurice Thorez')]
# [('politician', 'Maurice Thorez'), ('country', 'France'), ('spouse', 'Jeannette Vermeersch')]
# [('politician', 'Sandra Lonardo'), ('country', 'Italy'), ('spouse', 'Clemente Mastella')]
# [('politician', 'Clemente Mastella'), ('country', 'Italy'), ('spouse', 'Sandra Lonardo')]
# [('politician', 'John Adams'), ('country', 'France'), ('spouse', 'Abigail Adams')]
# [('politician', 'Simone Veil'), ('country', 'France'), ('spouse', 'Antoine Veil')]
# [('politician', 'Louis Philippe I'), ('country', 'France'), ('spouse', 'Maria Amalia of Naples and Sicily')]
# [('politician', 'Jean-Jacques Cottel'), ('country', 'France'), ('spouse', 'Édith Cottel')]
# [('politician', 'Pierre Abelin'), ('country', 'France'), ('spouse', 'Geneviève Abelin')]
# [('politician', 'Rita Montagnana'), ('country', 'Italy'), ('spouse', 'Palmiro Togliatti')]
# [('politician', 'Geneviève Abelin'), ('country', 'France'), ('spouse', 'Pierre Abelin')]
# [('politician', 'Marcelle Devaud'), ('country', 'France'), ('spouse', 'Stanislas Devaud')]
# [('politician', 'François Mitterrand'), ('country', 'France'), ('spouse', 'Danielle Mitterrand')]
# [('politician', 'Anne Poniatowski'), ('country', 'France'), ('spouse', 'Axel Poniatowski')]
# [('politician', 'Jean-Marc Germain'), ('country', 'France'), ('spouse', 'Anne Hidalgo')]
# [('politician', 'Danielle Mitterrand'), ('country', 'France'), ('spouse', 'François Mitterrand')]
# [('politician', 'Giovanni Kessler'), ('country', 'Italy'), ('spouse', 'Daria de Pretis')]
# [('politician', 'Daria de Pretis'), ('country', 'Italy'), ('spouse', 'Giovanni Kessler')]
# [('politician', 'Danilo Poggiolini'), ('country', 'Italy'), ('spouse', 'Carla Mazzuca Poggiolini')]
# [('politician', 'Carla Mazzuca Poggiolini'), ('country', 'Italy'), ('spouse', 'Danilo Poggiolini')]
# [('politician', 'Giuseppe Berti'), ('country', 'Italy'), ('spouse', 'Balda Di Vittorio')]
# [('politician', 'Nunzia De Girolamo'), ('country', 'Italy'), ('spouse', 'Francesco Boccia')]
# [('politician', 'Balda Di Vittorio'), ('country', 'Italy'), ('spouse', 'Giuseppe Berti')]
# [('politician', 'Angelo Raffaele Jervolino'), ('country', 'Italy'), ('spouse', 'Maria De Unterrichter Jervolino')]
# [('politician', 'Francesco Boccia'), ('country', 'Italy'), ('spouse', 'Nunzia De Girolamo')]
# [('politician', 'Yann Piat'), ('country', 'France'), ('spouse', 'François Bachelot')]
# [('politician', 'François Bachelot'), ('country', 'France'), ('spouse', 'Yann Piat')]
# [('politician', 'Raymonde Tillon'), ('country', 'France'), ('spouse', 'Charles Tillon')]
# [('politician', 'Charles Tillon'), ('country', 'France'), ('spouse', 'Raymonde Tillon')]
# [('politician', 'Antoine Veil'), ('country', 'France'), ('spouse', 'Simone Veil')]
# [('politician', "Anne d'Ornano"), ('country', 'France'), ('spouse', "Michel d'Ornano")]
# [('politician', "Valéry Giscard d'Estaing"), ('country', 'France'), ('spouse', "Anne-Aymone Giscard d'Estaing")]
# [('politician', 'Arthur Giovoni'), ('country', 'France'), ('spouse', 'Angèle Chevrin-Giovoni')]
# [('politician', 'Angèle Chevrin-Giovoni'), ('country', 'France'), ('spouse', 'Arthur Giovoni')]
# [('politician', 'Cendrine Blot'), ('country', 'France'), ('spouse', 'Yvan Blot')]
# [('politician', "Michel d'Ornano"), ('country', 'France'), ('spouse', "Anne d'Ornano")]
# [('politician', 'Robert Ménard'), ('country', 'France'), ('spouse', 'Emmanuelle Ménard')]
# [('politician', 'Penelope Fillon'), ('country', 'France'), ('spouse', 'François Fillon')]
# [('politician', 'Patrick Ollier'), ('country', 'France'), ('spouse', 'Michèle Alliot-Marie')]
# [('politician', 'Daniel Goulet'), ('country', 'France'), ('spouse', 'Nathalie Goulet')]
# [('politician', 'Marguerite Bayou'), ('country', 'France'), ('spouse', 'Raoul Bayou')]
# [('politician', 'Raoul Bayou'), ('country', 'France'), ('spouse', 'Marguerite Bayou')]
# [('politician', 'Colette Roulleaux-Dugage'), ('country', 'France'), ('spouse', 'Jacques Roulleaux-Dugage')]
# [('politician', 'Jacques Roulleaux-Dugage'), ('country', 'France'), ('spouse', 'Colette Roulleaux-Dugage')]
# [('politician', 'Raymond Patenôtre'), ('country', 'France'), ('spouse', 'Jacqueline Thome-Patenôtre')]
# [('politician', 'Aureliana Alberici'), ('country', 'Italy'), ('spouse', 'Achille Occhetto')]
# [('politician', 'Jacqueline Thome-Patenôtre'), ('country', 'France'), ('spouse', 'Raymond Patenôtre')]
# [('politician', 'Bruno Mégret'), ('country', 'France'), ('spouse', 'Catherine Mégret')]
# [('politician', 'Angela Filipponio Tatarella'), ('country', 'Italy'), ('spouse', 'Giuseppe Tatarella')]
# [('politician', 'Andrée Viénot'), ('country', 'France'), ('spouse', 'Pierre Viénot')]
# [('politician', 'Sylvia Bassot'), ('country', 'France'), ('spouse', 'Hubert Bassot')]
# [('politician', 'Hubert Bassot'), ('country', 'France'), ('spouse', 'Sylvia Bassot')]
# [('politician', 'Charles de Gaulle'), ('country', 'France'), ('spouse', 'Yvonne de Gaulle')]
# [('politician', 'Marie-Claude Vaillant-Couturier'), ('country', 'France'), ('spouse', 'Paul Vaillant-Couturier')]
# [('politician', 'Maria De Unterrichter Jervolino'), ('country', 'Italy'), ('spouse', 'Angelo Raffaele Jervolino')]
# [('politician', 'Alain Joissains'), ('country', 'France'), ('spouse', 'Maryse Joissains-Masini')]
# [('politician', 'Pascale Briand'), ('country', 'France'), ('spouse', 'Axel Kahn')]
# [('politician', 'Sylvie Andrieux'), ('country', 'France'), ('spouse', 'Jean-Paul Bacquet')]
# [('politician', 'Najat Vallaud-Belkacem'), ('country', 'France'), ('spouse', 'Boris Vallaud')]
# [('politician', 'Dominique Estrosi Sassone'), ('country', 'France'), ('spouse', 'Christian Estrosi')]
# [('politician', 'Nicole Bricq'), ('country', 'France'), ('spouse', 'Jean-Paul Planchou')]
# [('politician', 'Bernadette Païx'), ('country', 'France'), ('spouse', 'Jean-Claude Paix')]
# [('politician', 'Jean-Claude Paix'), ('country', 'France'), ('spouse', 'Bernadette Païx')]
# [('politician', 'Emmanuelle Ménard'), ('country', 'France'), ('spouse', 'Robert Ménard')]
# [('politician', 'Michèle Alliot-Marie'), ('country', 'France'), ('spouse', 'Patrick Ollier')]
# [('politician', 'Marie-Claude Vaillant-Couturier'), ('country', 'France'), ('spouse', 'Pierre Villon')]
# [('politician', 'Éric Raoult'), ('country', 'France'), ('spouse', 'Béatrice Abollivier')]
# [('politician', 'Nella Marcellino'), ('country', 'Italy'), ('spouse', 'Arturo Colombi')]
# [('politician', 'Béatrice Abollivier'), ('country', 'France'), ('spouse', 'Éric Raoult')]
# [('politician', 'Isabella Rauti'), ('country', 'Italy'), ('spouse', 'Gianni Alemanno')]
# [('politician', 'Édith Cottel'), ('country', 'France'), ('spouse', 'Jean-Jacques Cottel')]
# [('politician', 'Daniel Ouezzin Coulibaly'), ('country', 'France'), ('spouse', 'Célestine Ouezzin-Coulibaly')]
# [('politician', 'Célestine Ouezzin-Coulibaly'), ('country', 'France'), ('spouse', 'Daniel Ouezzin Coulibaly')]
# [('politician', 'Martino Corda'), ('country', 'Italy'), ('spouse', 'Simonetta Murru')]
# [('politician', 'Simonetta Murru'), ('country', 'Italy'), ('spouse', 'Martino Corda')]
# [('politician', 'Jean-Claude Pezet'), ('country', 'France'), ('spouse', 'Jocelyne Pezet-Romieux')]
# [('politician', 'Jocelyne Pezet-Romieux'), ('country', 'France'), ('spouse', 'Jean-Claude Pezet')]
# [('politician', 'Jean-Yves Le Drian'), ('country', 'France'), ('spouse', 'Maria Vadillo')]
# [('politician', 'Maria Vadillo'), ('country', 'France'), ('spouse', 'Jean-Yves Le Drian')]
# [('politician', 'Philippe Augier'), ('country', 'France'), ('spouse', 'Marielle de Sarnez')]
# [('politician', 'Philippe Christophe Hallez'), ('country', 'France'), ('spouse', 'Michel Marie Claparède')]
# [('politician', 'Alfredo Reichlin'), ('country', 'Italy'), ('spouse', 'Luciana Castellina')]
# [('politician', 'Claude-Annick Tissot'), ('country', 'France'), ('spouse', 'Alain Devaquet')]
# [('politician', 'Maryse Joissains-Masini'), ('country', 'France'), ('spouse', 'Alain Joissains')]
# [('politician', 'Alain Devaquet'), ('country', 'France'), ('spouse', 'Claude-Annick Tissot')]
# [('politician', 'Nathalie Goulet'), ('country', 'France'), ('spouse', 'Daniel Goulet')]
# [('politician', 'Anne Hidalgo'), ('country', 'France'), ('spouse', 'Jean-Marc Germain')]
# [('politician', 'Géraldine Vogel'), ('country', 'France'), ('spouse', 'Jean-Pierre Vogel')]
# [('politician', 'Jean-Pierre Vogel'), ('country', 'France'), ('spouse', 'Géraldine Vogel')]
# [('politician', 'Palmiro Togliatti'), ('country', 'Italy'), ('spouse', 'Rita Montagnana')]
# [('politician', 'Achille Occhetto'), ('country', 'Italy'), ('spouse', 'Aureliana Alberici')]
# [('politician', 'Monica Cirinnà'), ('country', 'Italy'), ('spouse', 'Esterino Montino')]
# [('politician', 'Esterino Montino'), ('country', 'Italy'), ('spouse', 'Monica Cirinnà')]
# [('politician', 'Lia Quartapelle'), ('country', 'Italy'), ('spouse', 'Claudio Martelli')]
# [('politician', 'Claudio Martelli'), ('country', 'Italy'), ('spouse', 'Lia Quartapelle')]
# [('politician', 'Nicolas Bays'), ('country', 'France'), ('spouse', 'Aurore Bergé')]
# [('politician', 'Jean-Paul Planchou'), ('country', 'France'), ('spouse', 'Nicole Bricq')]
# [('politician', 'François Missoffe'), ('country', 'France'), ('spouse', 'Hélène Missoffe')]
# [('politician', 'Hélène Missoffe'), ('country', 'France'), ('spouse', 'François Missoffe')]
# [('politician', 'Gianni Alemanno'), ('country', 'Italy'), ('spouse', 'Isabella Rauti')]
# [('politician', 'Georges Gosnat'), ('country', 'France'), ('spouse', 'Denise Bastide')]
# [('politician', 'Denise Bastide'), ('country', 'France'), ('spouse', 'Georges Gosnat')]
# [('politician', 'Axel Poniatowski'), ('country', 'France'), ('spouse', 'Anne Poniatowski')]
# [('politician', 'Jean-Pierre Stirbois'), ('country', 'France'), ('spouse', 'Marie-France Stirbois')]
# [('politician', 'Marie-France Stirbois'), ('country', 'France'), ('spouse', 'Jean-Pierre Stirbois')]
# [('politician', 'François Fillon'), ('country', 'France'), ('spouse', 'Penelope Fillon')]
# [('politician', 'Martine Daugreilh'), ('country', 'France'), ('spouse', 'Jean-Pierre Daugreilh')]
# [('politician', 'Jean-Pierre Daugreilh'), ('country', 'France'), ('spouse', 'Martine Daugreilh')]
# [('politician', 'Marielle de Sarnez'), ('country', 'France'), ('spouse', 'Philippe Augier')]
# [('politician', 'Yvan Blot'), ('country', 'France'), ('spouse', 'Cendrine Blot')]
# [('politician', 'Jean-Marie Le Chevallier'), ('country', 'France'), ('spouse', 'Cendrine Blot')]
# [('politician', 'Cendrine Blot'), ('country', 'France'), ('spouse', 'Jean-Marie Le Chevallier')]
# [('politician', 'Arturo Colombi'), ('country', 'Italy'), ('spouse', 'Nella Marcellino')]
# [('politician', 'Luciana Castellina'), ('country', 'Italy'), ('spouse', 'Alfredo Reichlin')]
# [('politician', 'Louis Luc'), ('country', 'France'), ('spouse', 'Hélène Luc')]
# [('politician', 'Hélène Luc'), ('country', 'France'), ('spouse', 'Louis Luc')]
# [('politician', 'Jacques Salvator'), ('country', 'France'), ('spouse', 'Évelyne Yonnet')]
# [('politician', 'Évelyne Yonnet'), ('country', 'France'), ('spouse', 'Jacques Salvator')]
# [('politician', 'Vincenza Bono'), ('country', 'Italy'), ('spouse', 'Francesco Parrino')]
# [('politician', 'Francesco Parrino'), ('country', 'Italy'), ('spouse', 'Vincenza Bono')]
# [('politician', 'Dario Ginefra'), ('country', 'Italy'), ('spouse', 'Laura Ravetto')]
# [('politician', 'Laura Ravetto'), ('country', 'Italy'), ('spouse', 'Dario Ginefra')]
# [('politician', 'Suzanne Sauvaigo'), ('country', 'France'), ('spouse', 'Pierre Sauvaigo')]
# [('politician', 'Pierre Sauvaigo'), ('country', 'France'), ('spouse', 'Suzanne Sauvaigo')]
# [('politician', 'Axel Kahn'), ('country', 'France'), ('spouse', 'Pascale Briand')]
# [('politician', 'Édith Gorce-Franklin'), ('country', 'France'), ('spouse', 'Henri Gorce-Franklin')]
# [('politician', 'Monique Huon'), ('country', 'France'), ('spouse', 'Jean Pot')]
# [('politician', 'Jean Pot'), ('country', 'France'), ('spouse', 'Monique Huon')]
# [('politician', 'Christian Estrosi'), ('country', 'France'), ('spouse', 'Dominique Estrosi Sassone')]
# [('politician', 'Jean-Paul Bacquet'), ('country', 'France'), ('spouse', 'Sylvie Andrieux')]
# [('politician', 'Pierre Lalumière'), ('country', 'France'), ('spouse', 'Catherine Lalumière')]
# [('politician', 'Catherine Lalumière'), ('country', 'France'), ('spouse', 'Pierre Lalumière')]
# [('politician', 'Jean-Claude Guibal'), ('country', 'France'), ('spouse', 'Colette Giudicelli')]
# [('politician', 'Colette Giudicelli'), ('country', 'France'), ('spouse', 'Jean-Claude Guibal')]
# [('politician', 'Henri Gorce-Franklin'), ('country', 'France'), ('spouse', 'Édith Gorce-Franklin')]
# 160

# %%
#Let's count the number of Italian and French politicians which had a spouse that is was also a politician 
queryString = """
SELECT ?country (COUNT(DISTINCT ?pol) AS ?num) 
WHERE { 

# ?pol wdt:P106/wdt:P279{0,2} wd:Q82955 ;
     wdt:P26 ?sp ;
     wdt:P39 ?pos .
# ?pos wdt:P17 ?cou .
# ?sp wdt:P106/wdt:P279{0,2} wd:Q82955 ;
    wdt:P39 ?pos1 .
# ?pos1 wdt:P17 ?cou1 .

FILTER(?cou = wd:Q142 || ?cou = wd:Q38) .

# ?cou <http://schema.org/name> ?country .

}
GROUP BY ?country

"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('country', 'France'), ('num', '124')]
# [('country', 'Italy'), ('num', '36')]
# 2

# %% [markdown]
# #### Comment
# The two queries above are answering the task and with the second one we can even verify the correcness of the results of the first.

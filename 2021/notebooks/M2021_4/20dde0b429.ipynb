# %% [markdown]
# # General instructions
#
# The goal of the project is to materialize a set of **exploratory workloads** over a real-world, large-scale,  open-domain KG: [WikiData](https://www.wikidata.org/wiki/Wikidata:Main_Page)
#
# An exploratory workload  is composed by a set of queries, where each query is related to the information obtained previously.
#
# An exploratory workload starts with a usually vague, open ended question, and does not assume the person issuing the workload has a clear understanding of the data contained in the target database or its structure.
#
# Remeber that:
#
# 1. All the queries must run in the python notebook
# 2. You can use classes and properties only if you find them via a SPARQL query that must be present in the notebook
# 3. You do not delete useless queries. Keep everything that is synthatically valid
#
# ```
# ?p <http://schema.org/name> ?name .
# ```
#
#     is the BGP returning a human-readable name of a property or a class in Wikidata.

# %%
## SETUP used later

from SPARQLWrapper import SPARQLWrapper, JSON


prefixString = """
##-20dde0b429-##
PREFIX wd: <http://www.wikidata.org/entity/> 
PREFIX wdt: <http://www.wikidata.org/prop/direct/> 
PREFIX sc: <http://schema.org/>
"""

# select and construct queries
def run_query(queryString):
    to_run = prefixString + "\n" + queryString

    sparql = SPARQLWrapper("http://a256-gc1-02.srv.aau.dk:5820/sparql")
    sparql.setTimeout(300)
    sparql.setReturnFormat(JSON)
    sparql.setQuery(to_run)

    try :
       results = sparql.query()
       json_results = results.convert()
       if len(json_results['results']['bindings'])==0:
          print("Empty")
          return 0
    
       for bindings in json_results['results']['bindings']:
          print( [ (var, value['value'])  for var, value in bindings.items() ] )

       return len(json_results['results']['bindings'])

    except Exception as e :
        print("The operation failed", e)
    
# ASk queries
def run_ask_query(queryString):
    to_run = prefixString + "\n" + queryString

    sparql = SPARQLWrapper("http://a256-gc1-03.srv.aau.dk:5820/sparql")
    sparql.setTimeout(300)
    sparql.setReturnFormat(JSON)
    sparql.setQuery(to_run)

    try :
        return sparql.query().convert()

    except Exception as e :
        print("The operation failed", e)

# %% [markdown]
# # Book Workflow Series ("Authors comparison explorative search")
#
# Consider the following exploratory scenario:
#
#
# >  Investigate the the production of Paul Auster and Ian McEwan, check how many books they have written for each litarature genre, gather information about their production and about their works which are not books
#
#
#
# ## Useful URIs for the current workflow
# The following are given:
#
# | IRI           | Description   | Role      |
# | -----------   | -----------   |-----------|
# | `wdt:P1647`   | subproperty   | predicate |
# | `wdt:P31`     | instance of   | predicate |
# | `wdt:P106`    | profession    | predicate |
# | `wdt:P279`    | subclass      | predicate |
# | `wd:Q47461344`| writtenwork   | node |
# | `wd:Q214642`  | Paul Auster   | node |
# | `wd:Q190379`  | Ian McEwan    | node |
#
#
#
#
# Also consider
#
# ```
# wd:Q214642 ?rel ?obj  .
# ```
# is the BGP to retrieve all **properties of Paul Auster**
#
#
# The workload should
#
#
# 1. Identify the BGP for obtaining the books (with publishing date and genre) published by the two authors
#
# 2. Did the authors published a book in the same year? What is the longest period without publishing a book for the two authors?
#
# 3. Did the authors produced, acted or directed a film? If so, did they write the screenplay?
#
# 4. How many films were derived from the books of these two authors?
#
# 5. Which author won more literature-related awards? Have they ever being nominated for a Nobel award?

# %% [markdown]
# #### Stato: In corso

# %% [markdown]
# #### Point 1 Start

# %%
# start your workflow here

# %%
queryString = """
SELECT COUNT( ?obj)
WHERE { 
wd:Q214642 ?rel ?obj  . 
} 
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('callret-0', '191')]
# 1

# %%
# Return nodes connected to Paul Auster
queryString = """
SELECT ?obj
WHERE { 

wd:Q214642 ?rel ?obj. 

} 
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('obj', 'http://wikiba.se/ontology#Item')]
# [('obj', 'http://data.bibliotheken.nl/id/thes/p072139331')]
# [('obj', 'https://livedata.bibsys.no/authority/90118966')]
# [('obj', 'http://rvk.uni-regensburg.de/nt/HU+3080')]
# [('obj', 'http://data.beeldengeluid.nl/gtaa/220930')]
# [('obj', 'http://viaf.org/viaf/110344312')]
# [('obj', 'http://id.worldcat.org/fast/84658')]
# [('obj', 'https://d-nb.info/gnd/11910251X')]
# [('obj', 'https://id.loc.gov/authorities/names/n81151642')]
# [('obj', 'http://vocab.getty.edu/ulan/500388357')]
# [('obj', 'http://data.bnf.fr/ark:/12148/cb13091337v#about')]
# [('obj', 'http://www.idref.fr/026697203/id')]
# [('obj', 'http://data.nlg.gr/resource/authority/record178541')]
# [('obj', 'http://id.ndl.go.jp/auth/ndlna/00462563')]
# [('obj', 'http://musicbrainz.org/artist/aa8f33f2-18c2-4617-be17-ad8231a950b3')]
# [('obj', 'http://lod.nl.go.kr/resource/KAC199601202')]
# [('obj', 'https://libris.kb.se/fcrtwjwz00xdb76')]
# [('obj', 'http://catalogo.pusc.it/auth/4589')]
# [('obj', 'http://g.co/kg/m/0683n')]
# [('obj', 'http://openlibrary.org/works/OL190100A')]
# [('obj', 'http://openlibrary.org/works/OL4944759A')]
# [('obj', 'https://data.rkd.nl/artists/380914')]
# [('obj', 'http://data.bibliotheken.nl/id/dbnla/aust004')]
# [('obj', 'http://data.europeana.eu/agent/base/60215')]
# [('obj', 'http://data.cinematheque.qc.ca/data/Person22264')]
# [('obj', 'http://libris.kb.se/resource/auth/232169')]
# [('obj', 'http://datos.bne.es/resource/XX1162838')]
# [('obj', '72675')]
# [('obj', '072139331')]
# [('obj', 'http://www.wikidata.org/entity/Q8242')]
# [('obj', '90118966')]
# [('obj', 'http://www.wikidata.org/entity/Q11774202')]
# [('obj', 'http://www.wikidata.org/entity/Q14467526')]
# [('obj', 'http://www.wikidata.org/entity/Q1622272')]
# [('obj', 'http://www.wikidata.org/entity/Q18814623')]
# [('obj', 'http://www.wikidata.org/entity/Q2526255')]
# [('obj', 'http://www.wikidata.org/entity/Q28389')]
# [('obj', 'http://www.wikidata.org/entity/Q333634')]
# [('obj', 'http://www.wikidata.org/entity/Q36180')]
# [('obj', 'http://www.wikidata.org/entity/Q482980')]
# [('obj', 'http://www.wikidata.org/entity/Q49757')]
# [('obj', 'http://www.wikidata.org/entity/Q6625963')]
# [('obj', 'http://www.wikidata.org/entity/Q49088')]
# [('obj', 'HU 3080')]
# [('obj', 'n96022626')]
# [('obj', '2789')]
# [('obj', '454/000033355')]
# [('obj', '22187')]
# [('obj', 'a10432097')]
# [('obj', '9698915')]
# [('obj', '00000019810')]
# [('obj', '18000000033')]
# [('obj', '0241019')]
# [('obj', 'vtls002620546')]
# [('obj', '1284869')]
# [('obj', '2006-01-01T00:00:00Z')]
# [('obj', 'http://www.wikidata.org/entity/Q67311526')]
# [('obj', 'http://www.wikidata.org/entity/Q676')]
# [('obj', '000004016')]
# [('obj', 'http://www.wikidata.org/entity/Q150')]
# [('obj', 'http://www.wikidata.org/entity/Q1860')]
# [('obj', 'biography/Paul-Auster')]
# [('obj', 'Paul Auster')]
# [('obj', 'a1273290')]
# [('obj', 'http://www.wikidata.org/entity/Q13452531')]
# [('obj', 'http://www.wikidata.org/entity/Q3332454')]
# [('obj', 'http://www.wikidata.org/entity/Q52382875')]
# [('obj', 'http://www.wikidata.org/entity/Q1188661')]
# [('obj', 'http://www.wikidata.org/entity/Q3405076')]
# [('obj', 'A11862105')]
# [('obj', 'mn0002055384')]
# [('obj', '220930')]
# [('obj', 'http://commons.wikimedia.org/wiki/Special:FilePath/Paul%20Auster%20in%20New%20York%20City%202008.jpg')]
# [('obj', 'http://www.wikidata.org/entity/Q25395')]
# [('obj', '476763')]
# [('obj', '9902')]
# [('obj', '59304')]
# [('obj', 'auster.paul')]
# [('obj', 'p188298')]
# [('obj', '1974-01-01T00:00:00Z')]
# [('obj', 'http://www.wikidata.org/entity/Q6581097')]
# [('obj', '0000 0001 2147 6081')]
# [('obj', '110344312')]
# [('obj', '84658')]
# [('obj', '213917')]
# [('obj', '35433')]
# [('obj', '31158')]
# [('obj', '10160')]
# [('obj', '11910251X')]
# [('obj', '164618')]
# [('obj', '23254')]
# [('obj', 'n81151642')]
# [('obj', '500388357')]
# [('obj', '9825')]
# [('obj', 'http://www.wikidata.org/entity/Q1280035')]
# [('obj', 'http://www.wikidata.org/entity/Q259543')]
# [('obj', '53773')]
# [('obj', '3969')]
# [('obj', '144092')]
# [('obj', 'people/paul-auster')]
# [('obj', '13091337v')]
# [('obj', '026697203')]
# [('obj', 'http://www.wikidata.org/entity/Q30')]
# [('obj', 'DA03307098')]
# [('obj', 'AusterPaul')]
# [('obj', '2681880')]
# [('obj', '296961')]
# [('obj', 'http://www.wikidata.org/entity/Q5')]
# [('obj', 'austepau')]
# [('obj', 'Paul+Auster')]
# [('obj', 'paul-auster')]
# [('obj', 'paul-auster')]
# [('obj', '178541')]
# [('obj', 'paul-auster')]
# [('obj', 'w6jd50fn')]
# [('obj', 'nm0000808')]
# [('obj', '00462563')]
# [('obj', 'literatuur-internationaal/paul-auster')]
# [('obj', '2660')]
# [('obj', 'Paul Auster')]
# [('obj', 'IT\\ICCU\\CFIV\\074948')]
# [('obj', '174671')]
# [('obj', 'http://www.wikidata.org/entity/Q445905')]
# [('obj', '36546797')]
# [('obj', 'pe/000776')]
# [('obj', 'aa8f33f2-18c2-4617-be17-ad8231a950b3')]
# [('obj', 'Paul_Auster')]
# [('obj', 'pessoa374591/paul-auster')]
# [('obj', 'http://www.wikidata.org/entity/Q7118978')]
# [('obj', 'http://www.wikidata.org/entity/Q463303')]
# [('obj', 'http://www.wikidata.org/entity/Q463281')]
# [('obj', '281880401')]
# [('obj', '12216')]
# [('obj', '46391')]
# [('obj', 'auster-paul')]
# [('obj', 'KAC199601202')]
# [('obj', '1895796')]
# [('obj', 'auster_paul')]
# [('obj', '593')]
# [('obj', 'a/paul-auster')]
# [('obj', '121')]
# [('obj', 'paul-auster')]
# [('obj', '17730')]
# [('obj', '-48485')]
# [('obj', 'fcrtwjwz00xdb76')]
# [('obj', 'paul-auster-1230')]
# [('obj', '1947-02-03T00:00:00Z')]
# [('obj', '4589')]
# [('obj', '6657')]
# [('obj', 'M00000022287')]
# [('obj', '790')]
# [('obj', 'http://www.wikidata.org/entity/Q188740')]
# [('obj', '/m/0683n')]
# [('obj', 'OL190100A')]
# [('obj', 'OL4944759A')]
# [('obj', '380914')]
# [('obj', '152138')]
# [('obj', 'http://www.wikidata.org/entity/Q49088')]
# [('obj', 'http://www.wikidata.org/entity/Q5149722')]
# [('obj', 'jo20000080478')]
# [('obj', 'http://www.wikidata.org/entity/Q7510954')]
# [('obj', 'aust004')]
# [('obj', '9810660639305606')]
# [('obj', 'http://www.wikidata.org/entity/Q16479919')]
# [('obj', 'http://www.wikidata.org/entity/Q4925623')]
# [('obj', 'Paul Benjamin')]
# [('obj', '4155')]
# [('obj', 'agent/base/60215')]
# [('obj', 'http://www.wikidata.org/entity/Q73555012')]
# [('obj', 'lccn-n81151642')]
# [('obj', '95a5yja38danygu695b5yc1q6gwk8e0')]
# [('obj', '11910251X')]
# [('obj', '4670')]
# [('obj', 'http://www.wikidata.org/entity/Q581485')]
# [('obj', 'http://www.wikidata.org/entity/Q1817920')]
# [('obj', 'http://www.wikidata.org/entity/Q1215203')]
# [('obj', 'http://www.wikidata.org/entity/Q1821899')]
# [('obj', '51668')]
# [('obj', 'http://paul-auster.com/')]
# [('obj', 'paul-auster')]
# [('obj', '13451')]
# [('obj', '17300581')]
# [('obj', '7302503')]
# [('obj', '22264')]
# [('obj', '232169')]
# [('obj', 'http://www.wikidata.org/entity/Q8718676')]
# [('obj', '409')]
# [('obj', '90499')]
# [('obj', 'p0004911-Auster-Paul-1947')]
# [('obj', 'XX1162838')]
# [('obj', 'Paul Auster')]
# 191

# %%
# Return understandable name about nodes connected to Paul Auster
queryString = """
SELECT ?obj ?name
WHERE { 

wd:Q214642 ?rel ?obj.
# ?obj <http://schema.org/name> ?name.

} 
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('obj', 'http://www.wikidata.org/entity/Q1280035'), ('name', 'Lydia Davis')]
# [('obj', 'http://www.wikidata.org/entity/Q581485'), ('name', 'The Book of Illusions')]
# [('obj', 'http://www.wikidata.org/entity/Q25395'), ('name', 'Newark')]
# [('obj', 'http://www.wikidata.org/entity/Q7118978'), ('name', 'PEN America')]
# [('obj', 'http://www.wikidata.org/entity/Q11774202'), ('name', 'essayist')]
# [('obj', 'http://www.wikidata.org/entity/Q13452531'), ('name', 'Commandeur des Arts et des Lettres\u200e')]
# [('obj', 'http://www.wikidata.org/entity/Q14467526'), ('name', 'linguist')]
# [('obj', 'http://www.wikidata.org/entity/Q150'), ('name', 'French')]
# [('obj', 'http://www.wikidata.org/entity/Q1622272'), ('name', 'university teacher')]
# [('obj', 'http://www.wikidata.org/entity/Q1860'), ('name', 'English')]
# [('obj', 'http://www.wikidata.org/entity/Q18814623'), ('name', 'autobiographer')]
# [('obj', 'http://www.wikidata.org/entity/Q188740'), ('name', 'Museum of Modern Art')]
# [('obj', 'http://www.wikidata.org/entity/Q2526255'), ('name', 'film director')]
# [('obj', 'http://www.wikidata.org/entity/Q28389'), ('name', 'screenwriter')]
# [('obj', 'http://www.wikidata.org/entity/Q30'), ('name', 'United States of America')]
# [('obj', 'http://www.wikidata.org/entity/Q3332454'), ('name', 'Princess of Asturias Literary Prize')]
# [('obj', 'http://www.wikidata.org/entity/Q333634'), ('name', 'translator')]
# [('obj', 'http://www.wikidata.org/entity/Q36180'), ('name', 'writer')]
# [('obj', 'http://www.wikidata.org/entity/Q463303'), ('name', 'American Academy of Arts and Sciences')]
# [('obj', 'http://www.wikidata.org/entity/Q482980'), ('name', 'author')]
# [('obj', 'http://www.wikidata.org/entity/Q49088'), ('name', 'Columbia University')]
# [('obj', 'http://www.wikidata.org/entity/Q49088'), ('name', 'Columbia University')]
# [('obj', 'http://www.wikidata.org/entity/Q4925623'), ('name', 'Paul')]
# [('obj', 'http://www.wikidata.org/entity/Q49757'), ('name', 'poet')]
# [('obj', 'http://www.wikidata.org/entity/Q5'), ('name', 'human')]
# [('obj', 'http://www.wikidata.org/entity/Q52382875'), ('name', 'AAAS Fellow')]
# [('obj', 'http://www.wikidata.org/entity/Q6581097'), ('name', 'male')]
# [('obj', 'http://www.wikidata.org/entity/Q6625963'), ('name', 'novelist')]
# [('obj', 'http://www.wikidata.org/entity/Q67311526'), ('name', 'Obalky knih.cz')]
# [('obj', 'http://www.wikidata.org/entity/Q676'), ('name', 'prose')]
# [('obj', 'http://www.wikidata.org/entity/Q73555012'), ('name', 'works protected by copyrights')]
# [('obj', 'http://www.wikidata.org/entity/Q8242'), ('name', 'literature')]
# [('obj', 'http://www.wikidata.org/entity/Q1188661'), ('name', 'PEN/Faulkner Award for Fiction')]
# [('obj', 'http://www.wikidata.org/entity/Q3405076'), ('name', 'Prix Médicis for foreign literature')]
# [('obj', 'http://www.wikidata.org/entity/Q463281'), ('name', 'American Academy of Arts and Letters')]
# [('obj', 'http://www.wikidata.org/entity/Q5149722'), ('name', 'Columbia High School')]
# [('obj', 'http://www.wikidata.org/entity/Q1817920'), ('name', 'Man in the Dark')]
# [('obj', 'http://www.wikidata.org/entity/Q7510954'), ('name', 'Category:Films directed by Paul Auster')]
# [('obj', 'http://www.wikidata.org/entity/Q259543'), ('name', 'Siri Hustvedt')]
# [('obj', 'http://www.wikidata.org/entity/Q1215203'), ('name', 'The New York Trilogy')]
# [('obj', 'http://www.wikidata.org/entity/Q8718676'), ('name', 'Category:Paul Auster')]
# [('obj', 'http://www.wikidata.org/entity/Q16479919'), ('name', 'Auster')]
# [('obj', 'http://www.wikidata.org/entity/Q1821899'), ('name', 'Leviathan')]
# [('obj', 'http://www.wikidata.org/entity/Q445905'), ('name', 'Sophie Auster')]
# 44

# %%
# Return understandable name about nodes connected to Paul Auster and their predicates
queryString = """
SELECT ?obj ?objName ?rel ?relName
WHERE { 

wd:Q214642 ?rel ?obj.
# ?obj <http://schema.org/name> ?objName.
# ?rel <http://schema.org/name> ?relName.

} 
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('obj', 'http://www.wikidata.org/entity/Q8242'), ('objName', 'literature'), ('rel', 'http://www.wikidata.org/prop/direct/P101'), ('relName', 'field of work')]
# [('obj', 'http://www.wikidata.org/entity/Q11774202'), ('objName', 'essayist'), ('rel', 'http://www.wikidata.org/prop/direct/P106'), ('relName', 'occupation')]
# [('obj', 'http://www.wikidata.org/entity/Q14467526'), ('objName', 'linguist'), ('rel', 'http://www.wikidata.org/prop/direct/P106'), ('relName', 'occupation')]
# [('obj', 'http://www.wikidata.org/entity/Q1622272'), ('objName', 'university teacher'), ('rel', 'http://www.wikidata.org/prop/direct/P106'), ('relName', 'occupation')]
# [('obj', 'http://www.wikidata.org/entity/Q18814623'), ('objName', 'autobiographer'), ('rel', 'http://www.wikidata.org/prop/direct/P106'), ('relName', 'occupation')]
# [('obj', 'http://www.wikidata.org/entity/Q2526255'), ('objName', 'film director'), ('rel', 'http://www.wikidata.org/prop/direct/P106'), ('relName', 'occupation')]
# [('obj', 'http://www.wikidata.org/entity/Q28389'), ('objName', 'screenwriter'), ('rel', 'http://www.wikidata.org/prop/direct/P106'), ('relName', 'occupation')]
# [('obj', 'http://www.wikidata.org/entity/Q333634'), ('objName', 'translator'), ('rel', 'http://www.wikidata.org/prop/direct/P106'), ('relName', 'occupation')]
# [('obj', 'http://www.wikidata.org/entity/Q36180'), ('objName', 'writer'), ('rel', 'http://www.wikidata.org/prop/direct/P106'), ('relName', 'occupation')]
# [('obj', 'http://www.wikidata.org/entity/Q482980'), ('objName', 'author'), ('rel', 'http://www.wikidata.org/prop/direct/P106'), ('relName', 'occupation')]
# [('obj', 'http://www.wikidata.org/entity/Q49757'), ('objName', 'poet'), ('rel', 'http://www.wikidata.org/prop/direct/P106'), ('relName', 'occupation')]
# [('obj', 'http://www.wikidata.org/entity/Q6625963'), ('objName', 'novelist'), ('rel', 'http://www.wikidata.org/prop/direct/P106'), ('relName', 'occupation')]
# [('obj', 'http://www.wikidata.org/entity/Q49088'), ('objName', 'Columbia University'), ('rel', 'http://www.wikidata.org/prop/direct/P108'), ('relName', 'employer')]
# [('obj', 'http://www.wikidata.org/entity/Q67311526'), ('objName', 'Obalky knih.cz'), ('rel', 'http://www.wikidata.org/prop/direct/P1343'), ('relName', 'described by source')]
# [('obj', 'http://www.wikidata.org/entity/Q676'), ('objName', 'prose'), ('rel', 'http://www.wikidata.org/prop/direct/P136'), ('relName', 'genre')]
# [('obj', 'http://www.wikidata.org/entity/Q150'), ('objName', 'French'), ('rel', 'http://www.wikidata.org/prop/direct/P1412'), ('relName', 'languages spoken, written or signed')]
# [('obj', 'http://www.wikidata.org/entity/Q1860'), ('objName', 'English'), ('rel', 'http://www.wikidata.org/prop/direct/P1412'), ('relName', 'languages spoken, written or signed')]
# [('obj', 'http://www.wikidata.org/entity/Q13452531'), ('objName', 'Commandeur des Arts et des Lettres\u200e'), ('rel', 'http://www.wikidata.org/prop/direct/P166'), ('relName', 'award received')]
# [('obj', 'http://www.wikidata.org/entity/Q3332454'), ('objName', 'Princess of Asturias Literary Prize'), ('rel', 'http://www.wikidata.org/prop/direct/P166'), ('relName', 'award received')]
# [('obj', 'http://www.wikidata.org/entity/Q52382875'), ('objName', 'AAAS Fellow'), ('rel', 'http://www.wikidata.org/prop/direct/P166'), ('relName', 'award received')]
# [('obj', 'http://www.wikidata.org/entity/Q1188661'), ('objName', 'PEN/Faulkner Award for Fiction'), ('rel', 'http://www.wikidata.org/prop/direct/P166'), ('relName', 'award received')]
# [('obj', 'http://www.wikidata.org/entity/Q3405076'), ('objName', 'Prix Médicis for foreign literature'), ('rel', 'http://www.wikidata.org/prop/direct/P166'), ('relName', 'award received')]
# [('obj', 'http://www.wikidata.org/entity/Q25395'), ('objName', 'Newark'), ('rel', 'http://www.wikidata.org/prop/direct/P19'), ('relName', 'place of birth')]
# [('obj', 'http://www.wikidata.org/entity/Q6581097'), ('objName', 'male'), ('rel', 'http://www.wikidata.org/prop/direct/P21'), ('relName', 'sex or gender')]
# [('obj', 'http://www.wikidata.org/entity/Q1280035'), ('objName', 'Lydia Davis'), ('rel', 'http://www.wikidata.org/prop/direct/P26'), ('relName', 'spouse')]
# [('obj', 'http://www.wikidata.org/entity/Q259543'), ('objName', 'Siri Hustvedt'), ('rel', 'http://www.wikidata.org/prop/direct/P26'), ('relName', 'spouse')]
# [('obj', 'http://www.wikidata.org/entity/Q30'), ('objName', 'United States of America'), ('rel', 'http://www.wikidata.org/prop/direct/P27'), ('relName', 'country of citizenship')]
# [('obj', 'http://www.wikidata.org/entity/Q5'), ('objName', 'human'), ('rel', 'http://www.wikidata.org/prop/direct/P31'), ('relName', 'instance of')]
# [('obj', 'http://www.wikidata.org/entity/Q445905'), ('objName', 'Sophie Auster'), ('rel', 'http://www.wikidata.org/prop/direct/P40'), ('relName', 'child')]
# [('obj', 'http://www.wikidata.org/entity/Q7118978'), ('objName', 'PEN America'), ('rel', 'http://www.wikidata.org/prop/direct/P463'), ('relName', 'member of')]
# [('obj', 'http://www.wikidata.org/entity/Q463303'), ('objName', 'American Academy of Arts and Sciences'), ('rel', 'http://www.wikidata.org/prop/direct/P463'), ('relName', 'member of')]
# [('obj', 'http://www.wikidata.org/entity/Q463281'), ('objName', 'American Academy of Arts and Letters'), ('rel', 'http://www.wikidata.org/prop/direct/P463'), ('relName', 'member of')]
# [('obj', 'http://www.wikidata.org/entity/Q188740'), ('objName', 'Museum of Modern Art'), ('rel', 'http://www.wikidata.org/prop/direct/P6379'), ('relName', 'has works in the collection')]
# [('obj', 'http://www.wikidata.org/entity/Q49088'), ('objName', 'Columbia University'), ('rel', 'http://www.wikidata.org/prop/direct/P69'), ('relName', 'educated at')]
# [('obj', 'http://www.wikidata.org/entity/Q5149722'), ('objName', 'Columbia High School'), ('rel', 'http://www.wikidata.org/prop/direct/P69'), ('relName', 'educated at')]
# [('obj', 'http://www.wikidata.org/entity/Q7510954'), ('objName', 'Category:Films directed by Paul Auster'), ('rel', 'http://www.wikidata.org/prop/direct/P7084'), ('relName', 'related category')]
# [('obj', 'http://www.wikidata.org/entity/Q16479919'), ('objName', 'Auster'), ('rel', 'http://www.wikidata.org/prop/direct/P734'), ('relName', 'family name')]
# [('obj', 'http://www.wikidata.org/entity/Q4925623'), ('objName', 'Paul'), ('rel', 'http://www.wikidata.org/prop/direct/P735'), ('relName', 'given name')]
# [('obj', 'http://www.wikidata.org/entity/Q73555012'), ('objName', 'works protected by copyrights'), ('rel', 'http://www.wikidata.org/prop/direct/P7763'), ('relName', 'copyright status as a creator')]
# [('obj', 'http://www.wikidata.org/entity/Q581485'), ('objName', 'The Book of Illusions'), ('rel', 'http://www.wikidata.org/prop/direct/P800'), ('relName', 'notable work')]
# [('obj', 'http://www.wikidata.org/entity/Q1817920'), ('objName', 'Man in the Dark'), ('rel', 'http://www.wikidata.org/prop/direct/P800'), ('relName', 'notable work')]
# [('obj', 'http://www.wikidata.org/entity/Q1215203'), ('objName', 'The New York Trilogy'), ('rel', 'http://www.wikidata.org/prop/direct/P800'), ('relName', 'notable work')]
# [('obj', 'http://www.wikidata.org/entity/Q1821899'), ('objName', 'Leviathan'), ('rel', 'http://www.wikidata.org/prop/direct/P800'), ('relName', 'notable work')]
# [('obj', 'http://www.wikidata.org/entity/Q8718676'), ('objName', 'Category:Paul Auster'), ('rel', 'http://www.wikidata.org/prop/direct/P910'), ('relName', "topic's main category")]
# 44

# %%
# Return information abount instances of writtenWork
queryString = """
SELECT ?instanceName
WHERE { 

wd:Q47461344 wdt:P31 ?instance.
# ?instance <http://schema.org/name> ?instanceName.

} 
"""

print("Results")
run_query(queryString)
# Out:
# Results
# Empty
# 0

# %%
# Return writtenWork information
queryString = """
SELECT ?instance
WHERE { 

wd:Q47461344 wdt:P31 ?instance.

} 
"""

print("Results")
run_query(queryString)
# Out:
# Results
# Empty
# 0

# %%
# Return all predicates of Paul Auster
queryString = """
SELECT distinct ?predicate ?predicateName
WHERE { 

wd:Q214642 ?predicate ?obj.
# ?predicate <http://schema.org/name> ?predicateName.

} 
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('predicate', 'http://www.wikidata.org/prop/direct/P1005'), ('predicateName', 'Portuguese National Library ID')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P1006'), ('predicateName', 'Nationale Thesaurus voor Auteurs ID')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P101'), ('predicateName', 'field of work')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P1015'), ('predicateName', 'NORAF ID')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P106'), ('predicateName', 'occupation')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P108'), ('predicateName', 'employer')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P1150'), ('predicateName', 'Regensburg Classification')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P1207'), ('predicateName', 'NUKAT ID')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P1233'), ('predicateName', 'Internet Speculative Fiction Database author ID')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P1263'), ('predicateName', 'NNDB people ID')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P1266'), ('predicateName', 'AlloCiné person ID')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P1273'), ('predicateName', 'CANTIC ID')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P1280'), ('predicateName', 'CONOR.SI ID')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P1284'), ('predicateName', 'Munzinger person ID')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P1289'), ('predicateName', 'Kritisches Lexikon zur fremdsprachigen Gegenwartsliteratur ID')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P1296'), ('predicateName', 'Gran Enciclopèdia Catalana ID')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P1309'), ('predicateName', 'EGAXA ID')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P1315'), ('predicateName', 'NLA Trove ID')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P1317'), ('predicateName', 'floruit')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P1343'), ('predicateName', 'described by source')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P136'), ('predicateName', 'genre')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P1368'), ('predicateName', 'LNB ID')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P1412'), ('predicateName', 'languages spoken, written or signed')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P1417'), ('predicateName', 'Encyclopædia Britannica Online ID')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P1559'), ('predicateName', 'name in native language')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P1580'), ('predicateName', 'University of Barcelona authority ID')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P166'), ('predicateName', 'award received')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P1695'), ('predicateName', 'NLP ID (unique)')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P1728'), ('predicateName', 'AllMusic artist ID')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P1741'), ('predicateName', 'GTAA ID')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P18'), ('predicateName', 'image')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P19'), ('predicateName', 'place of birth')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P1953'), ('predicateName', 'Discogs artist ID')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P1969'), ('predicateName', 'MovieMeter director ID (former scheme)')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P1977'), ('predicateName', 'Les Archives du Spectacle Person ID')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P2013'), ('predicateName', 'Facebook ID')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P2019'), ('predicateName', 'AllMovie person ID')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P2031'), ('predicateName', 'work period (start)')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P21'), ('predicateName', 'sex or gender')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P213'), ('predicateName', 'ISNI')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P214'), ('predicateName', 'VIAF ID')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P2163'), ('predicateName', 'FAST ID')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P2168'), ('predicateName', 'Swedish Film Database person ID')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P2174'), ('predicateName', 'Museum of Modern Art artist ID')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P2188'), ('predicateName', 'BiblioNet author ID')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P2191'), ('predicateName', 'Vegetti Catalog of Fantastic Literature NILF ID')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P227'), ('predicateName', 'GND ID')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P2387'), ('predicateName', 'Elonet person ID')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P2435'), ('predicateName', 'PORT person ID')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P244'), ('predicateName', 'Library of Congress authority ID')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P245'), ('predicateName', 'Union List of Artist Names ID')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P2519'), ('predicateName', 'Scope.dk person ID')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P26'), ('predicateName', 'spouse')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P2604'), ('predicateName', 'Kinopoisk person ID')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P2605'), ('predicateName', 'ČSFD person ID')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P2626'), ('predicateName', 'Danish National Filmography person ID')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P2638'), ('predicateName', 'TV.com ID')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P268'), ('predicateName', 'Bibliothèque nationale de France ID')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P269'), ('predicateName', 'IdRef ID')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P27'), ('predicateName', 'country of citizenship')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P271'), ('predicateName', 'CiNii author ID (books)')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P2734'), ('predicateName', 'Unz Review author ID')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P2924'), ('predicateName', 'Great Russian Encyclopedia Online ID')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P2963'), ('predicateName', 'Goodreads author ID')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P31'), ('predicateName', 'instance of')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P3154'), ('predicateName', 'Runeberg author ID')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P3192'), ('predicateName', 'Last.fm ID')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P3219'), ('predicateName', 'Encyclopædia Universalis ID')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P3222'), ('predicateName', 'NE.se ID')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P3348'), ('predicateName', 'National Library of Greece ID')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P3365'), ('predicateName', 'Treccani ID')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P3430'), ('predicateName', 'SNAC ARK ID')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P345'), ('predicateName', 'IMDb ID')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P349'), ('predicateName', 'National Diet Library ID')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P3569'), ('predicateName', 'Cultureel Woordenboek ID')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P3630'), ('predicateName', 'Babelio author ID')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P373'), ('predicateName', 'Commons category')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P396'), ('predicateName', 'SBN author ID')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P3987'), ('predicateName', 'SHARE Catalogue author ID')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P40'), ('predicateName', 'child')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P409'), ('predicateName', 'Libraries Australia ID')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P4293'), ('predicateName', 'PM20 folder ID')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P434'), ('predicateName', 'MusicBrainz artist ID')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P4342'), ('predicateName', 'Store norske leksikon ID')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P4399'), ('predicateName', 'Itaú Cultural ID')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P463'), ('predicateName', 'member of')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P4657'), ('predicateName', 'The Numbers person ID')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P4666'), ('predicateName', 'CineMagia person ID')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P4985'), ('predicateName', 'TMDb person ID')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P5019'), ('predicateName', 'Brockhaus Enzyklopädie online ID')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P5034'), ('predicateName', 'National Library of Korea ID')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P5068'), ('predicateName', 'Flanders Arts Institute person ID')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P5357'), ('predicateName', 'The Encyclopedia of Science Fiction ID')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P5377'), ('predicateName', 'Étonnants voyageurs participant ID')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P5408'), ('predicateName', 'Fantastic Fiction author ID')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P5414'), ('predicateName', 'The Paris Review interviewee ID')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P5419'), ('predicateName', 'NYRB contributor ID')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P5491'), ('predicateName', "BD Gest' author ID")]
# [('predicate', 'http://www.wikidata.org/prop/direct/P5570'), ('predicateName', 'NooSFere author ID')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P5587'), ('predicateName', 'Libris-URI')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P5617'), ('predicateName', 'Evene ID')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P569'), ('predicateName', 'date of birth')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P5739'), ('predicateName', 'Pontificia Università della Santa Croce ID')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P5821'), ('predicateName', 'ArhivX LOD')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P5882'), ('predicateName', 'Muziekweb performer ID')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P6173'), ('predicateName', 'Bitraga author ID')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P6379'), ('predicateName', 'has works in the collection')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P646'), ('predicateName', 'Freebase ID')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P648'), ('predicateName', 'Open Library ID')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P650'), ('predicateName', 'RKDartists ID')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P6844'), ('predicateName', 'abART person ID')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P69'), ('predicateName', 'educated at')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P691'), ('predicateName', 'NKCR AUT ID')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P7084'), ('predicateName', 'related category')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P723'), ('predicateName', 'Digitale Bibliotheek voor de Nederlandse Letteren author ID')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P7293'), ('predicateName', 'PLWABN ID')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P734'), ('predicateName', 'family name')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P735'), ('predicateName', 'given name')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P742'), ('predicateName', 'pseudonym')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P7433'), ('predicateName', 'FantLab author ID')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P7704'), ('predicateName', 'Europeana entity')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P7763'), ('predicateName', 'copyright status as a creator')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P7859'), ('predicateName', 'WorldCat Identities ID')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P7865'), ('predicateName', 'CoBiS author ID')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P7902'), ('predicateName', 'Deutsche Biographie (GND) ID')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P7982'), ('predicateName', 'Hrvatska enciklopedija ID')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P800'), ('predicateName', 'notable work')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P8349'), ('predicateName', 'Proleksis enciklopedija ID')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P856'), ('predicateName', 'official website')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P866'), ('predicateName', 'Perlentaucher ID')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P8795'), ('predicateName', 'General Diamond Catalogue ID')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P8849'), ('predicateName', 'CONOR.BG ID')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P8851'), ('predicateName', 'CONOR.SR ID')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P8971'), ('predicateName', 'Cinémathèque québécoise person ID')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P906'), ('predicateName', 'SELIBR ID')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P910'), ('predicateName', "topic's main category")]
# [('predicate', 'http://www.wikidata.org/prop/direct/P9141'), ('predicateName', 'Portal da Literatura ID')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P9251'), ('predicateName', 'Cyprus University of Technology ID')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P9322'), ('predicateName', 'SVKKL authority ID')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P950'), ('predicateName', 'Biblioteca Nacional de España ID')]
# 140

# %%
# Return all notableWorks of Paul Auster
queryString = """
SELECT distinct ?notableWork ?notableWorkName
WHERE { 

wd:Q214642 wdt:P800 ?notableWork.
# ?notableWork <http://schema.org/name> ?notableWorkName.

} 
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('notableWork', 'http://www.wikidata.org/entity/Q581485'), ('notableWorkName', 'The Book of Illusions')]
# [('notableWork', 'http://www.wikidata.org/entity/Q1817920'), ('notableWorkName', 'Man in the Dark')]
# [('notableWork', 'http://www.wikidata.org/entity/Q1215203'), ('notableWorkName', 'The New York Trilogy')]
# [('notableWork', 'http://www.wikidata.org/entity/Q1821899'), ('notableWorkName', 'Leviathan')]
# 4

# %%
# Return all notableWorks of Paul Auster with instance info
queryString = """
SELECT ?notableWorkName ?instanceOf
WHERE { 

wd:Q214642 wdt:P800 ?notableWork.
# ?notableWork <http://schema.org/name> ?notableWorkName.
# ?notableWork wdt:P31 ?instanceOf.

} 
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('notableWorkName', 'The Book of Illusions'), ('instanceOf', 'http://www.wikidata.org/entity/Q47461344')]
# [('notableWorkName', 'The Book of Illusions'), ('instanceOf', 'http://www.wikidata.org/entity/Q571')]
# [('notableWorkName', 'Man in the Dark'), ('instanceOf', 'http://www.wikidata.org/entity/Q47461344')]
# [('notableWorkName', 'The New York Trilogy'), ('instanceOf', 'http://www.wikidata.org/entity/Q277759')]
# [('notableWorkName', 'The New York Trilogy'), ('instanceOf', 'http://www.wikidata.org/entity/Q47461344')]
# [('notableWorkName', 'Leviathan'), ('instanceOf', 'http://www.wikidata.org/entity/Q47461344')]
# 6

# %%
# Return all notableWorks of Paul Auster with instance info
queryString = """
SELECT ?notableWorkName ?instanceOf ?instanceName
WHERE { 

wd:Q214642 wdt:P800 ?notableWork.
# ?notableWork <http://schema.org/name> ?notableWorkName.
# ?notableWork wdt:P31 ?instanceOf.
# ?instanceOf <http://schema.org/name> ?instanceName.
} 
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('notableWorkName', 'The New York Trilogy'), ('instanceOf', 'http://www.wikidata.org/entity/Q277759'), ('instanceName', 'book series')]
# [('notableWorkName', 'The New York Trilogy'), ('instanceOf', 'http://www.wikidata.org/entity/Q47461344'), ('instanceName', 'written work')]
# [('notableWorkName', 'The Book of Illusions'), ('instanceOf', 'http://www.wikidata.org/entity/Q47461344'), ('instanceName', 'written work')]
# [('notableWorkName', 'Leviathan'), ('instanceOf', 'http://www.wikidata.org/entity/Q47461344'), ('instanceName', 'written work')]
# [('notableWorkName', 'Man in the Dark'), ('instanceOf', 'http://www.wikidata.org/entity/Q47461344'), ('instanceName', 'written work')]
# [('notableWorkName', 'The Book of Illusions'), ('instanceOf', 'http://www.wikidata.org/entity/Q571'), ('instanceName', 'book')]
# 6

# %%
# Return all predicates about written work class
queryString = """
SELECT distinct ?predicate ?predicateName
WHERE { 

wd:Q47461344 ?predicate ?object.
# ?predicate <http://schema.org/name> ?predicateName.

} 
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('predicate', 'http://www.wikidata.org/prop/direct/P1889'), ('predicateName', 'different from')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P1963'), ('predicateName', 'properties for this type')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P2283'), ('predicateName', 'uses')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P279'), ('predicateName', 'subclass of')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P460'), ('predicateName', 'said to be the same as')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P8408'), ('predicateName', 'KBpedia ID')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P910'), ('predicateName', "topic's main category")]
# 7

# %%
# Return the written work superclass info of
queryString = """
SELECT distinct ?object ?objectName
WHERE { 

wd:Q47461344 wdt:P279 ?object.
# ?object <http://schema.org/name> ?objectName.

} 
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('object', 'http://www.wikidata.org/entity/Q17537576'), ('objectName', 'creative work')]
# 1

# %%
# Return all predicates about book class
queryString = """
SELECT distinct ?predicate ?predicateName
WHERE { 

wd:Q571 ?predicate ?object.
# ?predicate <http://schema.org/name> ?predicateName.

} 
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('predicate', 'http://www.wikidata.org/prop/direct/P1014'), ('predicateName', 'Art & Architecture Thesaurus ID')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P1036'), ('predicateName', 'Dewey Decimal Classification')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P1051'), ('predicateName', 'PSH ID')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P1151'), ('predicateName', "topic's main Wikimedia portal")]
# [('predicate', 'http://www.wikidata.org/prop/direct/P1225'), ('predicateName', 'U.S. National Archives Identifier')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P1245'), ('predicateName', 'OmegaWiki Defined Meaning')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P1256'), ('predicateName', 'Iconclass notation')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P1296'), ('predicateName', 'Gran Enciclopèdia Catalana ID')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P1343'), ('predicateName', 'described by source')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P1417'), ('predicateName', 'Encyclopædia Britannica Online ID')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P1424'), ('predicateName', "topic's main template")]
# [('predicate', 'http://www.wikidata.org/prop/direct/P1438'), ('predicateName', 'Jewish Encyclopedia ID (Russian)')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P1552'), ('predicateName', 'has quality')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P1617'), ('predicateName', 'BBC Things ID')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P1709'), ('predicateName', 'equivalent class')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P18'), ('predicateName', 'image')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P1889'), ('predicateName', 'different from')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P1963'), ('predicateName', 'properties for this type')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P2184'), ('predicateName', 'history of topic')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P2263'), ('predicateName', 'ISOCAT id')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P227'), ('predicateName', 'GND ID')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P2354'), ('predicateName', 'has list')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P244'), ('predicateName', 'Library of Congress authority ID')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P2581'), ('predicateName', 'BabelNet ID')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P2612'), ('predicateName', 'TED topic ID')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P268'), ('predicateName', 'Bibliothèque nationale de France ID')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P279'), ('predicateName', 'subclass of')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P2888'), ('predicateName', 'exact match')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P2959'), ('predicateName', 'permanent duplicated item')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P3106'), ('predicateName', 'Guardian topic ID')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P3219'), ('predicateName', 'Encyclopædia Universalis ID')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P3417'), ('predicateName', 'Quora topic ID')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P349'), ('predicateName', 'National Diet Library ID')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P3553'), ('predicateName', 'Zhihu topic ID')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P3612'), ('predicateName', 'Le Monde diplomatique subject ID')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P366'), ('predicateName', 'use')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P373'), ('predicateName', 'Commons category')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P3827'), ('predicateName', 'JSTOR topic ID')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P3832'), ('predicateName', 'Europeana Fashion Vocabulary ID')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P3916'), ('predicateName', 'UNESCO Thesaurus ID')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P3984'), ('predicateName', 'subreddit')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P4212'), ('predicateName', 'PACTOLS thesaurus ID')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P443'), ('predicateName', 'pronunciation audio')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P486'), ('predicateName', 'MeSH descriptor ID')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P487'), ('predicateName', 'Unicode character')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P4896'), ('predicateName', '3D model')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P5008'), ('predicateName', 'on focus list of Wikimedia project')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P5019'), ('predicateName', 'Brockhaus Enzyklopädie online ID')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P508'), ('predicateName', 'BNCF Thesaurus ID')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P51'), ('predicateName', 'audio')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P5125'), ('predicateName', 'Wikimedia outline')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P527'), ('predicateName', 'has part')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P5398'), ('predicateName', 'TDKIV term ID')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P5869'), ('predicateName', 'model item')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P6104'), ('predicateName', 'maintained by WikiProject')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P6200'), ('predicateName', 'BBC News topic ID')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P6404'), ('predicateName', "Treccani's Dizionario di Storia ID")]
# [('predicate', 'http://www.wikidata.org/prop/direct/P646'), ('predicateName', 'Freebase ID')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P6573'), ('predicateName', 'Klexikon article ID')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P6706'), ('predicateName', 'De Agostini ID')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P7033'), ('predicateName', 'Australian Educational Vocabulary ID')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P7497'), ('predicateName', 'Wolfram Language entity type')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P7749'), ('predicateName', 'Nomenclature for Museum Cataloging')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P7818'), ('predicateName', 'French Vikidia ID')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P7827'), ('predicateName', 'Spanish Vikidia ID')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P7829'), ('predicateName', 'English Vikidia ID')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P7844'), ('predicateName', 'Joconde object type ID')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P8406'), ('predicateName', 'Grove Art Online ID')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P8408'), ('predicateName', 'KBpedia ID')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P8519'), ('predicateName', 'RKD thesaurus ID')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P8672'), ('predicateName', 'Twitter topic ID')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P8814'), ('predicateName', 'WordNet 3.1 Synset ID')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P902'), ('predicateName', 'HDS ID')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P910'), ('predicateName', "topic's main category")]
# [('predicate', 'http://www.wikidata.org/prop/direct/P9100'), ('predicateName', 'GitHub topic')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P9318'), ('predicateName', 'Ávvir topic ID')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P935'), ('predicateName', 'Commons gallery')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P950'), ('predicateName', 'Biblioteca Nacional de España ID')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P989'), ('predicateName', 'spoken text audio')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P4167'), ('predicateName', 'Dagens Næringsliv topic ID')]
# 80

# %%
# Return info about book superclass
queryString = """
SELECT distinct ?object ?objectName
WHERE { 


wd:Q571 wdt:P279 ?object.
# ?object <http://schema.org/name> ?objectName.

} 
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('object', 'http://www.wikidata.org/entity/Q49848'), ('objectName', 'document')]
# [('object', 'http://www.wikidata.org/entity/Q2342494'), ('objectName', 'collectible')]
# [('object', 'http://www.wikidata.org/entity/Q732577'), ('objectName', 'publication')]
# [('object', 'http://www.wikidata.org/entity/Q47461344'), ('objectName', 'written work')]
# 4

# %%
#Return all predicates connecting an object of class written works with Paul Auster
queryString = """
SELECT distinct ?predicate ?predicateName
WHERE { 

# ?writtenWork wdt:P31 wd:Q47461344.
# ?writtenWork ?predicate wd:Q214642.
# ?predicate <http://schema.org/name> ?predicateName.

} 
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('predicate', 'http://www.wikidata.org/prop/direct/P50'), ('predicateName', 'author')]
# 1

# %%
#Return all predicates connecting Paul Auster with an object of the class written work
queryString = """
SELECT ?predicate ?predicateName
WHERE { 

wd:Q214642 ?predicate ?writtenWork.
# ?writtenWork wdt:P31 wd:Q47461344.
# ?predicate <http://schema.org/name> ?predicateName.

} 
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('predicate', 'http://www.wikidata.org/prop/direct/P800'), ('predicateName', 'notable work')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P800'), ('predicateName', 'notable work')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P800'), ('predicateName', 'notable work')]
# [('predicate', 'http://www.wikidata.org/prop/direct/P800'), ('predicateName', 'notable work')]
# 4

# %%
#Return all properties of written works
queryString = """
SELECT distinct ?property ?propertyName
WHERE { 

# ?writtenWork wdt:P31 wd:Q47461344.
# ?writtenWork ?property ?obj.
# ?property <http://schema.org/name> ?propertyName.


} 
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('property', 'http://www.wikidata.org/prop/direct/P872'), ('propertyName', 'printed by')]
# [('property', 'http://www.wikidata.org/prop/direct/P2093'), ('propertyName', 'author name string')]
# [('property', 'http://www.wikidata.org/prop/direct/P7357'), ('propertyName', 'Diccionari de la Literatura Catalana ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7487'), ('propertyName', 'Kinematoscope literary work ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P9256'), ('propertyName', 'Diccionari de la traducció catalana ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4738'), ('propertyName', 'Yale Center for British Art artwork ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P101'), ('propertyName', 'field of work')]
# [('property', 'http://www.wikidata.org/prop/direct/P1085'), ('propertyName', 'LibraryThing work ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P110'), ('propertyName', 'illustrator')]
# [('property', 'http://www.wikidata.org/prop/direct/P1104'), ('propertyName', 'number of pages')]
# [('property', 'http://www.wikidata.org/prop/direct/P1144'), ('propertyName', 'Library of Congress Control Number (LCCN) (bibliographic)')]
# [('property', 'http://www.wikidata.org/prop/direct/P1149'), ('propertyName', 'Library of Congress Classification')]
# [('property', 'http://www.wikidata.org/prop/direct/P123'), ('propertyName', 'publisher')]
# [('property', 'http://www.wikidata.org/prop/direct/P1235'), ('propertyName', 'ISFDB series ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1296'), ('propertyName', 'Gran Enciclopèdia Catalana ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1343'), ('propertyName', 'described by source')]
# [('property', 'http://www.wikidata.org/prop/direct/P136'), ('propertyName', 'genre')]
# [('property', 'http://www.wikidata.org/prop/direct/P138'), ('propertyName', 'named after')]
# [('property', 'http://www.wikidata.org/prop/direct/P1417'), ('propertyName', 'Encyclopædia Britannica Online ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1434'), ('propertyName', 'takes place in fictional universe')]
# [('property', 'http://www.wikidata.org/prop/direct/P144'), ('propertyName', 'based on')]
# [('property', 'http://www.wikidata.org/prop/direct/P1476'), ('propertyName', 'title')]
# [('property', 'http://www.wikidata.org/prop/direct/P155'), ('propertyName', 'follows')]
# [('property', 'http://www.wikidata.org/prop/direct/P156'), ('propertyName', 'followed by')]
# [('property', 'http://www.wikidata.org/prop/direct/P1580'), ('propertyName', 'University of Barcelona authority ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P166'), ('propertyName', 'award received')]
# [('property', 'http://www.wikidata.org/prop/direct/P1695'), ('propertyName', 'NLP ID (unique)')]
# [('property', 'http://www.wikidata.org/prop/direct/P17'), ('propertyName', 'country')]
# [('property', 'http://www.wikidata.org/prop/direct/P170'), ('propertyName', 'creator')]
# [('property', 'http://www.wikidata.org/prop/direct/P179'), ('propertyName', 'part of the series')]
# [('property', 'http://www.wikidata.org/prop/direct/P18'), ('propertyName', 'image')]
# [('property', 'http://www.wikidata.org/prop/direct/P180'), ('propertyName', 'depicts')]
# [('property', 'http://www.wikidata.org/prop/direct/P1814'), ('propertyName', 'name in kana')]
# [('property', 'http://www.wikidata.org/prop/direct/P1889'), ('propertyName', 'different from')]
# [('property', 'http://www.wikidata.org/prop/direct/P1922'), ('propertyName', 'first line')]
# [('property', 'http://www.wikidata.org/prop/direct/P2002'), ('propertyName', 'Twitter username')]
# [('property', 'http://www.wikidata.org/prop/direct/P2013'), ('propertyName', 'Facebook ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2048'), ('propertyName', 'height')]
# [('property', 'http://www.wikidata.org/prop/direct/P214'), ('propertyName', 'VIAF ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2191'), ('propertyName', 'Vegetti Catalog of Fantastic Literature NILF ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P227'), ('propertyName', 'GND ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2339'), ('propertyName', 'BoardGameGeek ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P243'), ('propertyName', 'OCLC control number')]
# [('property', 'http://www.wikidata.org/prop/direct/P244'), ('propertyName', 'Library of Congress authority ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2581'), ('propertyName', 'BabelNet ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2671'), ('propertyName', 'Google Knowledge Graph ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P268'), ('propertyName', 'Bibliothèque nationale de France ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P269'), ('propertyName', 'IdRef ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P291'), ('propertyName', 'place of publication')]
# [('property', 'http://www.wikidata.org/prop/direct/P31'), ('propertyName', 'instance of')]
# [('property', 'http://www.wikidata.org/prop/direct/P3123'), ('propertyName', 'Stanford Encyclopedia of Philosophy ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3219'), ('propertyName', 'Encyclopædia Universalis ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3417'), ('propertyName', 'Quora topic ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P361'), ('propertyName', 'part of')]
# [('property', 'http://www.wikidata.org/prop/direct/P3631'), ('propertyName', 'Babelio work ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P373'), ('propertyName', 'Commons category')]
# [('property', 'http://www.wikidata.org/prop/direct/P407'), ('propertyName', 'language of work or name')]
# [('property', 'http://www.wikidata.org/prop/direct/P409'), ('propertyName', 'Libraries Australia ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P436'), ('propertyName', 'MusicBrainz release group ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P443'), ('propertyName', 'pronunciation audio')]
# [('property', 'http://www.wikidata.org/prop/direct/P462'), ('propertyName', 'color')]
# [('property', 'http://www.wikidata.org/prop/direct/P4839'), ('propertyName', 'Wolfram Language entity code')]
# [('property', 'http://www.wikidata.org/prop/direct/P495'), ('propertyName', 'country of origin')]
# [('property', 'http://www.wikidata.org/prop/direct/P4969'), ('propertyName', 'derivative work')]
# [('property', 'http://www.wikidata.org/prop/direct/P50'), ('propertyName', 'author')]
# [('property', 'http://www.wikidata.org/prop/direct/P527'), ('propertyName', 'has part')]
# [('property', 'http://www.wikidata.org/prop/direct/P5331'), ('propertyName', 'OCLC work ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5396'), ('propertyName', 'Online Books Page publication ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P571'), ('propertyName', 'inception')]
# [('property', 'http://www.wikidata.org/prop/direct/P576'), ('propertyName', 'dissolved, abolished or demolished date')]
# [('property', 'http://www.wikidata.org/prop/direct/P577'), ('propertyName', 'publication date')]
# [('property', 'http://www.wikidata.org/prop/direct/P6216'), ('propertyName', 'copyright status')]
# [('property', 'http://www.wikidata.org/prop/direct/P646'), ('propertyName', 'Freebase ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P648'), ('propertyName', 'Open Library ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P655'), ('propertyName', 'translator')]
# [('property', 'http://www.wikidata.org/prop/direct/P674'), ('propertyName', 'characters')]
# [('property', 'http://www.wikidata.org/prop/direct/P6839'), ('propertyName', 'TV Tropes identifier')]
# [('property', 'http://www.wikidata.org/prop/direct/P691'), ('propertyName', 'NKCR AUT ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7042'), ('propertyName', 'The Latin Library author ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P724'), ('propertyName', 'Internet Archive ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P735'), ('propertyName', 'given name')]
# [('property', 'http://www.wikidata.org/prop/direct/P747'), ('propertyName', 'has edition or translation')]
# [('property', 'http://www.wikidata.org/prop/direct/P767'), ('propertyName', 'contributor to the creative work or subject')]
# [('property', 'http://www.wikidata.org/prop/direct/P7818'), ('propertyName', 'French Vikidia ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P8345'), ('propertyName', 'media franchise')]
# [('property', 'http://www.wikidata.org/prop/direct/P8383'), ('propertyName', 'Goodreads work ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P840'), ('propertyName', 'narrative location')]
# [('property', 'http://www.wikidata.org/prop/direct/P8411'), ('propertyName', 'set in environment')]
# [('property', 'http://www.wikidata.org/prop/direct/P856'), ('propertyName', 'official website')]
# [('property', 'http://www.wikidata.org/prop/direct/P8687'), ('propertyName', 'social media followers')]
# [('property', 'http://www.wikidata.org/prop/direct/P88'), ('propertyName', 'commissioned by')]
# [('property', 'http://www.wikidata.org/prop/direct/P8885'), ('propertyName', 'Namuwiki ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P910'), ('propertyName', "topic's main category")]
# [('property', 'http://www.wikidata.org/prop/direct/P921'), ('propertyName', 'main subject')]
# [('property', 'http://www.wikidata.org/prop/direct/P941'), ('propertyName', 'inspired by')]
# [('property', 'http://www.wikidata.org/prop/direct/P949'), ('propertyName', 'National Library of Israel ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P950'), ('propertyName', 'Biblioteca Nacional de España ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P953'), ('propertyName', 'full work available at URL')]
# [('property', 'http://www.wikidata.org/prop/direct/P98'), ('propertyName', 'editor')]
# [('property', 'http://www.wikidata.org/prop/direct/P1433'), ('propertyName', 'published in')]
# [('property', 'http://www.wikidata.org/prop/direct/P3132'), ('propertyName', 'last line')]
# [('property', 'http://www.wikidata.org/prop/direct/P1274'), ('propertyName', 'ISFDB title ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1680'), ('propertyName', 'subtitle')]
# [('property', 'http://www.wikidata.org/prop/direct/P212'), ('propertyName', 'ISBN-13')]
# [('property', 'http://www.wikidata.org/prop/direct/P2408'), ('propertyName', 'set in period')]
# [('property', 'http://www.wikidata.org/prop/direct/P3675'), ('propertyName', 'Hans Christian Andersen Centre work ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3959'), ('propertyName', 'NNL item ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5571'), ('propertyName', 'NooSFere book ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5846'), ('propertyName', 'AnimeClick novel ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6175'), ('propertyName', 'Bitraga work ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P629'), ('propertyName', 'edition or translation of')]
# [('property', 'http://www.wikidata.org/prop/direct/P736'), ('propertyName', 'cover art by')]
# [('property', 'http://www.wikidata.org/prop/direct/P7439'), ('propertyName', 'FantLab work ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P8359'), ('propertyName', 'Dewey Decimal Classification (works and editions)')]
# [('property', 'http://www.wikidata.org/prop/direct/P8360'), ('propertyName', 'Library of Congress Classification (works and editions)')]
# [('property', 'http://www.wikidata.org/prop/direct/P9215'), ('propertyName', 'set during recurring event')]
# [('property', 'http://www.wikidata.org/prop/direct/P957'), ('propertyName', 'ISBN-10')]
# [('property', 'http://www.wikidata.org/prop/direct/P2034'), ('propertyName', 'Project Gutenberg ebook ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2969'), ('propertyName', 'Goodreads version/edition ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3462'), ('propertyName', 'FAMA work ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7010'), ('propertyName', 'imprimatur granted by')]
# [('property', 'http://www.wikidata.org/prop/direct/P304'), ('propertyName', 'page(s)')]
# [('property', 'http://www.wikidata.org/prop/direct/P356'), ('propertyName', 'DOI')]
# [('property', 'http://www.wikidata.org/prop/direct/P8608'), ('propertyName', 'Fatcat ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7150'), ('propertyName', 'epigraph (literature)')]
# [('property', 'http://www.wikidata.org/prop/direct/P6166'), ('propertyName', 'quotes work')]
# [('property', 'http://www.wikidata.org/prop/direct/P135'), ('propertyName', 'movement')]
# [('property', 'http://www.wikidata.org/prop/direct/P1375'), ('propertyName', 'NSK ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1411'), ('propertyName', 'nominated for')]
# [('property', 'http://www.wikidata.org/prop/direct/P1545'), ('propertyName', 'series ordinal')]
# [('property', 'http://www.wikidata.org/prop/direct/P1670'), ('propertyName', 'Canadiana Authorities ID (former scheme)')]
# [('property', 'http://www.wikidata.org/prop/direct/P3280'), ('propertyName', 'BAnQ author ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3365'), ('propertyName', 'Treccani ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P349'), ('propertyName', 'National Diet Library ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P364'), ('propertyName', 'original language of film or TV show')]
# [('property', 'http://www.wikidata.org/prop/direct/P3847'), ('propertyName', 'Open Library subject ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4212'), ('propertyName', 'PACTOLS thesaurus ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4342'), ('propertyName', 'Store norske leksikon ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P435'), ('propertyName', 'MusicBrainz work ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P437'), ('propertyName', 'distribution format')]
# [('property', 'http://www.wikidata.org/prop/direct/P580'), ('propertyName', 'start time')]
# [('property', 'http://www.wikidata.org/prop/direct/P5986'), ('propertyName', 'Getty Iconography Authority ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6262'), ('propertyName', 'Fandom article ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6573'), ('propertyName', 'Klexikon article ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7293'), ('propertyName', 'PLWABN ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7699'), ('propertyName', 'National Library of Lithuania ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7823'), ('propertyName', 'BookBrainz work ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P8179'), ('propertyName', 'Canadiana NCF ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P8189'), ('propertyName', 'National Library of Israel J9U ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P8408'), ('propertyName', 'KBpedia ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P973'), ('propertyName', 'described at URL')]
# [('property', 'http://www.wikidata.org/prop/direct/P675'), ('propertyName', 'Google Books ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P8070'), ('propertyName', 'ToposText work ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P8632'), ('propertyName', 'Book Marks ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1823'), ('propertyName', 'BAnQ work ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6218'), ('propertyName', 'Genius song ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P8311'), ('propertyName', 'PHI Latin Texts work ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1025'), ('propertyName', 'SUDOC editions')]
# [('property', 'http://www.wikidata.org/prop/direct/P2187'), ('propertyName', 'BiblioNet publication ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2683'), ('propertyName', 'Bekker Number')]
# [('property', 'http://www.wikidata.org/prop/direct/P1242'), ('propertyName', 'Theatricalia play ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6679'), ('propertyName', 'Encyklopedia Teatru Polskiego play ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1219'), ('propertyName', 'Internet Broadway Database show ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1809'), ('propertyName', 'choreographer')]
# [('property', 'http://www.wikidata.org/prop/direct/P1292'), ('propertyName', 'DNB editions')]
# [('property', 'http://www.wikidata.org/prop/direct/P8248'), ('propertyName', 'Colon Classification')]
# [('property', 'http://www.wikidata.org/prop/direct/P86'), ('propertyName', 'composer')]
# [('property', 'http://www.wikidata.org/prop/direct/P9365'), ('propertyName', 'Modernist Commons ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P989'), ('propertyName', 'spoken text audio')]
# [('property', 'http://www.wikidata.org/prop/direct/P1191'), ('propertyName', 'date of first performance')]
# [('property', 'http://www.wikidata.org/prop/direct/P4647'), ('propertyName', 'location of first performance')]
# [('property', 'http://www.wikidata.org/prop/direct/P8211'), ('propertyName', 'Bookogs work ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1265'), ('propertyName', 'AlloCiné film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P154'), ('propertyName', 'logo image')]
# [('property', 'http://www.wikidata.org/prop/direct/P1687'), ('propertyName', 'Wikidata property')]
# [('property', 'http://www.wikidata.org/prop/direct/P213'), ('propertyName', 'ISNI')]
# [('property', 'http://www.wikidata.org/prop/direct/P3222'), ('propertyName', 'NE.se ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3553'), ('propertyName', 'Zhihu topic ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3827'), ('propertyName', 'JSTOR topic ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4211'), ('propertyName', 'Bashkir encyclopedia (Russian version) ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5008'), ('propertyName', 'on focus list of Wikimedia project')]
# [('property', 'http://www.wikidata.org/prop/direct/P7212'), ('propertyName', 'LyricsTranslate ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7859'), ('propertyName', 'WorldCat Identities ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7993'), ('propertyName', "Treccani's Dizionario di Filosofia ID")]
# [('property', 'http://www.wikidata.org/prop/direct/P8168'), ('propertyName', 'FactGrid item ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P9549'), ('propertyName', 'official podcast')]
# [('property', 'http://www.wikidata.org/prop/direct/P4517'), ('propertyName', 'ctext work ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P8312'), ('propertyName', 'Musisque Deoque work ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2679'), ('propertyName', 'author of foreword')]
# [('property', 'http://www.wikidata.org/prop/direct/P1054'), ('propertyName', 'NDL bib ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P478'), ('propertyName', 'volume')]
# [('property', 'http://www.wikidata.org/prop/direct/P6721'), ('propertyName', 'K10plus PPN ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1113'), ('propertyName', 'number of episodes')]
# [('property', 'http://www.wikidata.org/prop/direct/P1438'), ('propertyName', 'Jewish Encyclopedia ID (Russian)')]
# [('property', 'http://www.wikidata.org/prop/direct/P1705'), ('propertyName', 'native label')]
# [('property', 'http://www.wikidata.org/prop/direct/P2163'), ('propertyName', 'FAST ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2437'), ('propertyName', 'number of seasons')]
# [('property', 'http://www.wikidata.org/prop/direct/P2465'), ('propertyName', 'Allcinema film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2603'), ('propertyName', 'Kinopoisk film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P276'), ('propertyName', 'location')]
# [('property', 'http://www.wikidata.org/prop/direct/P345'), ('propertyName', 'IMDb ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3569'), ('propertyName', 'Cultureel Woordenboek ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3710'), ('propertyName', 'Jewish Encyclopedia Daat ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P449'), ('propertyName', 'original broadcaster')]
# [('property', 'http://www.wikidata.org/prop/direct/P4835'), ('propertyName', 'TheTVDB.com series ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4983'), ('propertyName', 'TMDb TV series ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5801'), ('propertyName', 'Academia.edu topic ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P582'), ('propertyName', 'end time')]
# [('property', 'http://www.wikidata.org/prop/direct/P6366'), ('propertyName', 'Microsoft Academic ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6385'), ('propertyName', 'Krugosvet article')]
# [('property', 'http://www.wikidata.org/prop/direct/P641'), ('propertyName', 'sport')]
# [('property', 'http://www.wikidata.org/prop/direct/P7305'), ('propertyName', 'Online PWN Encyclopedia ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P737'), ('propertyName', 'influenced by')]
# [('property', 'http://www.wikidata.org/prop/direct/P7937'), ('propertyName', 'form of creative work')]
# [('property', 'http://www.wikidata.org/prop/direct/P8406'), ('propertyName', 'Grove Art Online ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P9000'), ('propertyName', 'World History Encyclopedia ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P9106'), ('propertyName', 'Oxford Classical Dictionary ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P8091'), ('propertyName', 'Archival Resource Key')]
# [('property', 'http://www.wikidata.org/prop/direct/P6580'), ('propertyName', 'National Book Foundation book ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1044'), ('propertyName', 'SWB editions')]
# [('property', 'http://www.wikidata.org/prop/direct/P2008'), ('propertyName', 'IPNI publication ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2860'), ('propertyName', 'cites work')]
# [('property', 'http://www.wikidata.org/prop/direct/P1055'), ('propertyName', 'NLM Unique ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1273'), ('propertyName', 'CANTIC ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1424'), ('propertyName', "topic's main template")]
# [('property', 'http://www.wikidata.org/prop/direct/P159'), ('propertyName', 'headquarters location')]
# [('property', 'http://www.wikidata.org/prop/direct/P2635'), ('propertyName', 'number of parts of this work')]
# [('property', 'http://www.wikidata.org/prop/direct/P2812'), ('propertyName', 'MathWorld identifier')]
# [('property', 'http://www.wikidata.org/prop/direct/P282'), ('propertyName', 'writing system')]
# [('property', 'http://www.wikidata.org/prop/direct/P2888'), ('propertyName', 'exact match')]
# [('property', 'http://www.wikidata.org/prop/direct/P2924'), ('propertyName', 'Great Russian Encyclopedia Online ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4215'), ('propertyName', 'nLab ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5769'), ('propertyName', 'editor-in-chief')]
# [('property', 'http://www.wikidata.org/prop/direct/P6058'), ('propertyName', 'Larousse ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1877'), ('propertyName', 'after a work by')]
# [('property', 'http://www.wikidata.org/prop/direct/P433'), ('propertyName', 'issue')]
# [('property', 'http://www.wikidata.org/prop/direct/P6781'), ('propertyName', 'ProofWiki ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5878'), ('propertyName', 'Taxonomic Literature 2 number')]
# [('property', 'http://www.wikidata.org/prop/direct/P698'), ('propertyName', 'PubMed ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1407'), ('propertyName', 'MusicBrainz series ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1256'), ('propertyName', 'Iconclass notation')]
# [('property', 'http://www.wikidata.org/prop/direct/P1412'), ('propertyName', 'languages spoken, written or signed')]
# [('property', 'http://www.wikidata.org/prop/direct/P1566'), ('propertyName', 'GeoNames ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1617'), ('propertyName', 'BBC Things ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1813'), ('propertyName', 'short name')]
# [('property', 'http://www.wikidata.org/prop/direct/P1881'), ('propertyName', 'list of characters')]
# [('property', 'http://www.wikidata.org/prop/direct/P1890'), ('propertyName', 'CCAB ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P195'), ('propertyName', 'collection')]
# [('property', 'http://www.wikidata.org/prop/direct/P4549'), ('propertyName', 'ARLIMA ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4619'), ('propertyName', 'National Library of Brazil ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5021'), ('propertyName', 'assessment')]
# [('property', 'http://www.wikidata.org/prop/direct/P6706'), ('propertyName', 'De Agostini ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7314'), ('propertyName', 'TDV İslam Ansiklopedisi ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7369'), ('propertyName', 'National Library of Chile ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7506'), ('propertyName', 'Naver Encyclopedia ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7822'), ('propertyName', 'Italian Vikidia ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7829'), ('propertyName', 'English Vikidia ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P902'), ('propertyName', 'HDS ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P906'), ('propertyName', 'SELIBR ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P935'), ('propertyName', 'Commons gallery')]
# [('property', 'http://www.wikidata.org/prop/direct/P948'), ('propertyName', 'page banner')]
# [('property', 'http://www.wikidata.org/prop/direct/P9545'), ('propertyName', 'Encyclopedia of China Online Database ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1071'), ('propertyName', 'location of creation')]
# [('property', 'http://www.wikidata.org/prop/direct/P6442'), ('propertyName', 'Douban book version/edition ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P8294'), ('propertyName', 'AusStage work ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5485'), ('propertyName', 'SBN books ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3732'), ('propertyName', 'PhilPapers record')]
# [('property', 'http://www.wikidata.org/prop/direct/P8074'), ('propertyName', 'Geschichtsquellen des deutschen Mittelalters work ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1739'), ('propertyName', 'CiNii book ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3929'), ('propertyName', 'V&A item ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6135'), ('propertyName', 'VD 18 ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6201'), ('propertyName', 'OBV editions ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7609'), ('propertyName', 'SHARE Catalogue work ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1036'), ('propertyName', 'Dewey Decimal Classification')]
# [('property', 'http://www.wikidata.org/prop/direct/P1042'), ('propertyName', 'ZDB ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1249'), ('propertyName', 'time of earliest written record')]
# [('property', 'http://www.wikidata.org/prop/direct/P1552'), ('propertyName', 'has quality')]
# [('property', 'http://www.wikidata.org/prop/direct/P1957'), ('propertyName', 'Wikisource index page URL')]
# [('property', 'http://www.wikidata.org/prop/direct/P2348'), ('propertyName', 'time period')]
# [('property', 'http://www.wikidata.org/prop/direct/P2959'), ('propertyName', 'permanent duplicated item')]
# [('property', 'http://www.wikidata.org/prop/direct/P3021'), ('propertyName', 'Iranica ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3478'), ('propertyName', 'Songkick artist ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5088'), ('propertyName', 'Internet Encyclopedia of Philosophy ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5749'), ('propertyName', 'Amazon Standard Identification Number')]
# [('property', 'http://www.wikidata.org/prop/direct/P5909'), ('propertyName', 'HKCAN ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P996'), ('propertyName', 'document file on Wikimedia Commons')]
# [('property', 'http://www.wikidata.org/prop/direct/P5792'), ('propertyName', 'NooSFere series ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1474'), ('propertyName', 'BLPL document ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7103'), ('propertyName', 'start of covered period')]
# [('property', 'http://www.wikidata.org/prop/direct/P7104'), ('propertyName', 'end of covered period')]
# [('property', 'http://www.wikidata.org/prop/direct/P4361'), ('propertyName', 'ExecutedToday ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P127'), ('propertyName', 'owned by')]
# [('property', 'http://www.wikidata.org/prop/direct/P1807'), ('propertyName', 'Great Aragonese Encyclopedia ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P393'), ('propertyName', 'edition number')]
# [('property', 'http://www.wikidata.org/prop/direct/P6947'), ('propertyName', 'Goodreads series ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1844'), ('propertyName', 'HathiTrust ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1017'), ('propertyName', 'Vatican Library ID (former scheme)')]
# [('property', 'http://www.wikidata.org/prop/direct/P1258'), ('propertyName', 'Rotten Tomatoes ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1482'), ('propertyName', 'Stack Exchange tag')]
# [('property', 'http://www.wikidata.org/prop/direct/P1562'), ('propertyName', 'AllMovie title ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2529'), ('propertyName', 'ČSFD film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2631'), ('propertyName', 'TCM Movie Database film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2638'), ('propertyName', 'TV.com ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3138'), ('propertyName', 'OFDb film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3235'), ('propertyName', 'PhilPapers topic')]
# [('property', 'http://www.wikidata.org/prop/direct/P4529'), ('propertyName', 'Douban film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P480'), ('propertyName', 'FilmAffinity ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4947'), ('propertyName', 'TMDb movie ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5063'), ('propertyName', 'Interlingual Index ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5395'), ('propertyName', 'Canadian Encyclopedia article ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P57'), ('propertyName', 'director')]
# [('property', 'http://www.wikidata.org/prop/direct/P58'), ('propertyName', 'screenwriter')]
# [('property', 'http://www.wikidata.org/prop/direct/P5905'), ('propertyName', 'Comic Vine ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6127'), ('propertyName', 'Letterboxd film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6584'), ('propertyName', 'Scripts.com script ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P750'), ('propertyName', 'distributed by')]
# [('property', 'http://www.wikidata.org/prop/direct/P8814'), ('propertyName', 'WordNet 3.1 Synset ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4028'), ('propertyName', 'Google Scholar paper ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4230'), ('propertyName', 'Sefaria ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3342'), ('propertyName', 'significant person')]
# [('property', 'http://www.wikidata.org/prop/direct/P793'), ('propertyName', 'significant event')]
# [('property', 'http://www.wikidata.org/prop/direct/P3194'), ('propertyName', 'INA video ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1269'), ('propertyName', 'facet of')]
# [('property', 'http://www.wikidata.org/prop/direct/P140'), ('propertyName', 'religion')]
# [('property', 'http://www.wikidata.org/prop/direct/P2043'), ('propertyName', 'length')]
# [('property', 'http://www.wikidata.org/prop/direct/P5019'), ('propertyName', 'Brockhaus Enzyklopädie online ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4904'), ('propertyName', 'Tropicos publication ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4327'), ('propertyName', 'BHL bibliography ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P175'), ('propertyName', 'performer')]
# [('property', 'http://www.wikidata.org/prop/direct/P264'), ('propertyName', 'record label')]
# [('property', 'http://www.wikidata.org/prop/direct/P5495'), ('propertyName', 'Mormon Literature and Creative Arts Database Works ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3181'), ('propertyName', 'OpenCitations bibliographic resource ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2551'), ('propertyName', 'used metre')]
# [('property', 'http://www.wikidata.org/prop/direct/P1014'), ('propertyName', 'Art & Architecture Thesaurus ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1051'), ('propertyName', 'PSH ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P106'), ('propertyName', 'occupation')]
# [('property', 'http://www.wikidata.org/prop/direct/P1114'), ('propertyName', 'quantity')]
# [('property', 'http://www.wikidata.org/prop/direct/P1151'), ('propertyName', "topic's main Wikimedia portal")]
# [('property', 'http://www.wikidata.org/prop/direct/P1245'), ('propertyName', 'OmegaWiki Defined Meaning')]
# [('property', 'http://www.wikidata.org/prop/direct/P158'), ('propertyName', 'seal image')]
# [('property', 'http://www.wikidata.org/prop/direct/P2579'), ('propertyName', 'studied by')]
# [('property', 'http://www.wikidata.org/prop/direct/P279'), ('propertyName', 'subclass of')]
# [('property', 'http://www.wikidata.org/prop/direct/P3183'), ('propertyName', 'Wall Street Journal topic ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3241'), ('propertyName', 'Catholic Encyclopedia ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3348'), ('propertyName', 'National Library of Greece ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4073'), ('propertyName', 'Fandom wiki ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4210'), ('propertyName', 'Bashkir encyclopedia (Bashkir version) ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4254'), ('propertyName', 'Bengali Banglapedia ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4255'), ('propertyName', 'Banglapedia (English version) ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P460'), ('propertyName', 'said to be the same as')]
# [('property', 'http://www.wikidata.org/prop/direct/P5198'), ('propertyName', 'ASC Leiden Thesaurus ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5429'), ('propertyName', 'IPTC NewsCode')]
# [('property', 'http://www.wikidata.org/prop/direct/P5587'), ('propertyName', 'Libris-URI')]
# [('property', 'http://www.wikidata.org/prop/direct/P7208'), ('propertyName', 'Liber Liber author ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7312'), ('propertyName', 'Aozora Bunko work ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7749'), ('propertyName', 'Nomenclature for Museum Cataloging')]
# [('property', 'http://www.wikidata.org/prop/direct/P7775'), ('propertyName', 'RationalWiki ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7832'), ('propertyName', 'Basque Vikidia ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P8895'), ('propertyName', 'All the Tropes identifier')]
# [('property', 'http://www.wikidata.org/prop/direct/P898'), ('propertyName', 'IPA transcription')]
# [('property', 'http://www.wikidata.org/prop/direct/P9100'), ('propertyName', 'GitHub topic')]
# [('property', 'http://www.wikidata.org/prop/direct/P9223'), ('propertyName', 'Provenio UUID')]
# [('property', 'http://www.wikidata.org/prop/direct/P9286'), ('propertyName', 'Encyclopaedia Herder concept ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P9322'), ('propertyName', 'SVKKL authority ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P972'), ('propertyName', 'catalog')]
# [('property', 'http://www.wikidata.org/prop/direct/P5816'), ('propertyName', 'state of conservation')]
# [('property', 'http://www.wikidata.org/prop/direct/P3976'), ('propertyName', 'BVMC work ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P8978'), ('propertyName', 'DBLP publication ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7677'), ('propertyName', 'gesetze-im-internet.de ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P9696'), ('propertyName', 'Buzer.de law identification')]
# [('property', 'http://www.wikidata.org/prop/direct/P1001'), ('propertyName', 'applies to jurisdiction')]
# [('property', 'http://www.wikidata.org/prop/direct/P1225'), ('propertyName', 'U.S. National Archives Identifier')]
# [('property', 'http://www.wikidata.org/prop/direct/P1842'), ('propertyName', 'Global Anabaptist Mennonite Encyclopedia Online ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2003'), ('propertyName', 'Instagram username')]
# [('property', 'http://www.wikidata.org/prop/direct/P2347'), ('propertyName', 'YSO ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2354'), ('propertyName', 'has list')]
# [('property', 'http://www.wikidata.org/prop/direct/P2670'), ('propertyName', 'has parts of the class')]
# [('property', 'http://www.wikidata.org/prop/direct/P2910'), ('propertyName', 'icon')]
# [('property', 'http://www.wikidata.org/prop/direct/P3221'), ('propertyName', 'New York Times topic ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3308'), ('propertyName', 'lib.reviews ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3576'), ('propertyName', 'TLG author ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3630'), ('propertyName', 'Babelio author ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4223'), ('propertyName', "Treccani's Enciclopedia Italiana ID")]
# [('property', 'http://www.wikidata.org/prop/direct/P4235'), ('propertyName', 'PatientsLikeMe treatment ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4354'), ('propertyName', 'search formatter URL')]
# [('property', 'http://www.wikidata.org/prop/direct/P467'), ('propertyName', 'legislated by')]
# [('property', 'http://www.wikidata.org/prop/direct/P486'), ('propertyName', 'MeSH descriptor ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5002'), ('propertyName', 'Orthodox Encyclopedia ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5125'), ('propertyName', 'Wikimedia outline')]
# [('property', 'http://www.wikidata.org/prop/direct/P5739'), ('propertyName', 'Pontificia Università della Santa Croce ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5748'), ('propertyName', 'Basisklassifikation')]
# [('property', 'http://www.wikidata.org/prop/direct/P6104'), ('propertyName', 'maintained by WikiProject')]
# [('property', 'http://www.wikidata.org/prop/direct/P6404'), ('propertyName', "Treccani's Dizionario di Storia ID")]
# [('property', 'http://www.wikidata.org/prop/direct/P672'), ('propertyName', 'MeSH tree code')]
# [('property', 'http://www.wikidata.org/prop/direct/P6900'), ('propertyName', 'NicoNicoPedia ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7865'), ('propertyName', 'CoBiS author ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7935'), ('propertyName', 'Corpus Corporum author ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7982'), ('propertyName', 'Hrvatska enciklopedija ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P8065'), ('propertyName', 'CIRIS author ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P825'), ('propertyName', 'dedicated to')]
# [('property', 'http://www.wikidata.org/prop/direct/P8472'), ('propertyName', 'Encyclopedie berbere keyword ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P8514'), ('propertyName', 'TOPCMB ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P8519'), ('propertyName', 'RKD thesaurus ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P9037'), ('propertyName', 'BHCL UUID')]
# [('property', 'http://www.wikidata.org/prop/direct/P920'), ('propertyName', 'LEM ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P9629'), ('propertyName', 'Armeniapedia ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5940'), ('propertyName', 'plot expanded in')]
# [('property', 'http://www.wikidata.org/prop/direct/P8391'), ('propertyName', 'BBK (library and bibliographic classification)')]
# [('property', 'http://www.wikidata.org/prop/direct/P4436'), ('propertyName', 'The Coptic Library ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5337'), ('propertyName', 'Google News topics ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1651'), ('propertyName', 'YouTube video ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P272'), ('propertyName', 'production company')]
# [('property', 'http://www.wikidata.org/prop/direct/P3762'), ('propertyName', 'openMLOL author ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1015'), ('propertyName', 'NORAF ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1368'), ('propertyName', 'LNB ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P275'), ('propertyName', 'copyright license')]
# [('property', 'http://www.wikidata.org/prop/direct/P348'), ('propertyName', 'software version identifier')]
# [('property', 'http://www.wikidata.org/prop/direct/P6665'), ('propertyName', 'Pro-Linux.de DBApp ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6802'), ('propertyName', 'related image')]
# [('property', 'http://www.wikidata.org/prop/direct/P7502'), ('propertyName', 'Golden ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P9563'), ('propertyName', 'Encyclopedia of Renaissance Philosophy ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3112'), ('propertyName', 'DistroWatch ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4101'), ('propertyName', 'dissertation submitted to')]
# [('property', 'http://www.wikidata.org/prop/direct/P746'), ('propertyName', 'date of disappearance')]
# [('property', 'http://www.wikidata.org/prop/direct/P4854'), ('propertyName', 'Uppslagsverket Finland ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3962'), ('propertyName', 'Global Trade Item Number')]
# [('property', 'http://www.wikidata.org/prop/direct/P2737'), ('propertyName', 'union of')]
# [('property', 'http://www.wikidata.org/prop/direct/P131'), ('propertyName', 'located in the administrative territorial entity')]
# [('property', 'http://www.wikidata.org/prop/direct/P360'), ('propertyName', 'is a list of')]
# [('property', 'http://www.wikidata.org/prop/direct/P421'), ('propertyName', 'located in time zone')]
# [('property', 'http://www.wikidata.org/prop/direct/P2440'), ('propertyName', 'transliteration')]
# [('property', 'http://www.wikidata.org/prop/direct/P8513'), ('propertyName', 'LibraryThing series ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4151'), ('propertyName', 'game mechanics')]
# [('property', 'http://www.wikidata.org/prop/direct/P575'), ('propertyName', 'time of discovery or invention')]
# [('property', 'http://www.wikidata.org/prop/direct/P7226'), ('propertyName', 'RPGGeek ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7236'), ('propertyName', 'Dove.org work ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3589'), ('propertyName', 'GCD series ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3023'), ('propertyName', 'Legacies of British Slave-ownership person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P8612'), ('propertyName', 'past Fellow of the Royal Society ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P642'), ('propertyName', 'of')]
# [('property', 'http://www.wikidata.org/prop/direct/P8361'), ('propertyName', 'Universal Decimal Classification (works and editions)')]
# [('property', 'http://www.wikidata.org/prop/direct/P1005'), ('propertyName', 'Portuguese National Library ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1006'), ('propertyName', 'Nationale Thesaurus voor Auteurs ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P102'), ('propertyName', 'member of political party')]
# [('property', 'http://www.wikidata.org/prop/direct/P103'), ('propertyName', 'native language')]
# [('property', 'http://www.wikidata.org/prop/direct/P119'), ('propertyName', 'place of burial')]
# [('property', 'http://www.wikidata.org/prop/direct/P1207'), ('propertyName', 'NUKAT ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1263'), ('propertyName', 'NNDB people ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1299'), ('propertyName', 'depicted by')]
# [('property', 'http://www.wikidata.org/prop/direct/P1315'), ('propertyName', 'NLA Trove ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1415'), ('propertyName', 'Oxford Dictionary of National Biography ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1711'), ('propertyName', 'British Museum person or institution ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1816'), ('propertyName', 'National Portrait Gallery (London) person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1819'), ('propertyName', 'genealogics.org person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P186'), ('propertyName', 'made from material')]
# [('property', 'http://www.wikidata.org/prop/direct/P1871'), ('propertyName', 'CERL Thesaurus ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P19'), ('propertyName', 'place of birth')]
# [('property', 'http://www.wikidata.org/prop/direct/P20'), ('propertyName', 'place of death')]
# [('property', 'http://www.wikidata.org/prop/direct/P2049'), ('propertyName', 'width')]
# [('property', 'http://www.wikidata.org/prop/direct/P21'), ('propertyName', 'sex or gender')]
# [('property', 'http://www.wikidata.org/prop/direct/P22'), ('propertyName', 'father')]
# [('property', 'http://www.wikidata.org/prop/direct/P236'), ('propertyName', 'ISSN')]
# [('property', 'http://www.wikidata.org/prop/direct/P25'), ('propertyName', 'mother')]
# [('property', 'http://www.wikidata.org/prop/direct/P26'), ('propertyName', 'spouse')]
# [('property', 'http://www.wikidata.org/prop/direct/P2600'), ('propertyName', 'Geni.com profile ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2610'), ('propertyName', 'thickness')]
# [('property', 'http://www.wikidata.org/prop/direct/P27'), ('propertyName', 'country of citizenship')]
# [('property', 'http://www.wikidata.org/prop/direct/P2799'), ('propertyName', 'BVMC person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2949'), ('propertyName', 'WikiTree person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2966'), ('propertyName', 'National Library of Wales Authority ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2977'), ('propertyName', 'LBT person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3029'), ('propertyName', 'UK National Archives ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3051'), ('propertyName', 'Kindred Britain ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3373'), ('propertyName', 'sibling')]
# [('property', 'http://www.wikidata.org/prop/direct/P3429'), ('propertyName', 'Electronic Enlightenment ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3430'), ('propertyName', 'SNAC ARK ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P39'), ('propertyName', 'position held')]
# ...
# [('property', 'http://www.wikidata.org/prop/direct/P306'), ('propertyName', 'operating system')]
# [('property', 'http://www.wikidata.org/prop/direct/P3065'), ('propertyName', 'RERO ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P479'), ('propertyName', 'input method')]
# [('property', 'http://www.wikidata.org/prop/direct/P370'), ('propertyName', 'Sandbox-String')]
# [('property', 'http://www.wikidata.org/prop/direct/P5047'), ('propertyName', 'Rosetta Code ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3302'), ('propertyName', 'Open Media Database film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4780'), ('propertyName', 'MYmovies movie ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P9302'), ('propertyName', 'script style')]
# [('property', 'http://www.wikidata.org/prop/direct/P410'), ('propertyName', 'military rank')]
# [('property', 'http://www.wikidata.org/prop/direct/P1811'), ('propertyName', 'list of episodes')]
# [('property', 'http://www.wikidata.org/prop/direct/P5357'), ('propertyName', 'The Encyclopedia of Science Fiction ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6720'), ('propertyName', 'interwiki prefix at Wikimedia')]
# [('property', 'http://www.wikidata.org/prop/direct/P1984'), ('propertyName', 'Anime News Network manga ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4086'), ('propertyName', 'MyAnimeList anime ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5845'), ('propertyName', 'AnimeClick anime ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P725'), ('propertyName', 'voice actor')]
# [('property', 'http://www.wikidata.org/prop/direct/P8670'), ('propertyName', 'character designer')]
# [('property', 'http://www.wikidata.org/prop/direct/P4109'), ('propertyName', 'URN-NBN')]
# [('property', 'http://www.wikidata.org/prop/direct/P7457'), ('propertyName', "creator's signature")]
# [('property', 'http://www.wikidata.org/prop/direct/P1954'), ('propertyName', 'Discogs master ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P9555'), ('propertyName', 'Michigan State University Library Comic Art Collection Record Number')]
# [('property', 'http://www.wikidata.org/prop/direct/P827'), ('propertyName', 'BBC programme ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P54'), ('propertyName', 'member of sports team')]
# [('property', 'http://www.wikidata.org/prop/direct/P1938'), ('propertyName', 'Project Gutenberg author ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P287'), ('propertyName', 'designed by')]
# [('property', 'http://www.wikidata.org/prop/direct/P1686'), ('propertyName', 'for work')]
# [('property', 'http://www.wikidata.org/prop/direct/P1280'), ('propertyName', 'CONOR.SI ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2896'), ('propertyName', 'publication interval')]
# [('property', 'http://www.wikidata.org/prop/direct/P9234'), ('propertyName', 'supplement to')]
# [('property', 'http://www.wikidata.org/prop/direct/P4801'), ('propertyName', 'LoC and MARC vocabularies ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1817'), ('propertyName', 'addressee')]
# [('property', 'http://www.wikidata.org/prop/direct/P2680'), ('propertyName', 'author of afterword')]
# [('property', 'http://www.wikidata.org/prop/direct/P1462'), ('propertyName', 'standards body')]
# [('property', 'http://www.wikidata.org/prop/direct/P676'), ('propertyName', 'lyrics by')]
# [('property', 'http://www.wikidata.org/prop/direct/P2913'), ('propertyName', 'date depicted')]
# [('property', 'http://www.wikidata.org/prop/direct/P5505'), ('propertyName', 'WorldCat Registry ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1365'), ('propertyName', 'replaces')]
# [('property', 'http://www.wikidata.org/prop/direct/P1479'), ('propertyName', 'has contributing factor')]
# [('property', 'http://www.wikidata.org/prop/direct/P5123'), ('propertyName', 'Swedish Literature Bank edition')]
# [('property', 'http://www.wikidata.org/prop/direct/P687'), ('propertyName', 'BHL Page ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4258'), ('propertyName', 'Gallica ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5062'), ('propertyName', 'DOAB publisher ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6409'), ('propertyName', 'CORE ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4204'), ('propertyName', 'The Times of India topic ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P551'), ('propertyName', 'residence')]
# [('property', 'http://www.wikidata.org/prop/direct/P1973'), ('propertyName', 'RSL editions')]
# [('property', 'http://www.wikidata.org/prop/direct/P2687'), ('propertyName', 'NDL JPNO')]
# [('property', 'http://www.wikidata.org/prop/direct/P6520'), ('propertyName', 'Lokalhistoriewiki.no ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7037'), ('propertyName', 'COURAGE ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P108'), ('propertyName', 'employer')]
# [('property', 'http://www.wikidata.org/prop/direct/P4700'), ('propertyName', 'Cairn publication ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P8156'), ('propertyName', 'NKAA ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2664'), ('propertyName', 'units sold')]
# [('property', 'http://www.wikidata.org/prop/direct/P6153'), ('propertyName', 'research site')]
# [('property', 'http://www.wikidata.org/prop/direct/P5390'), ('propertyName', 'Classiques des sciences sociales ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4300'), ('propertyName', 'YouTube playlist ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7421'), ('propertyName', 'line(s)')]
# [('property', 'http://www.wikidata.org/prop/direct/P6962'), ('propertyName', 'narrative motif')]
# [('property', 'http://www.wikidata.org/prop/direct/P371'), ('propertyName', 'presenter')]
# [('property', 'http://www.wikidata.org/prop/direct/P7137'), ('propertyName', 'acknowledged')]
# [('property', 'http://www.wikidata.org/prop/direct/P7107'), ('propertyName', 'LezWatch.TV show ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5733'), ('propertyName', 'bilibili ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7091'), ('propertyName', 'Common Sense Media ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P894'), ('propertyName', 'zbMATH work ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5820'), ('propertyName', 'Film Indonesia ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4989'), ('propertyName', 'RKDlibrary ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6982'), ('propertyName', 'Australian Faunal Directory publication ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4431'), ('propertyName', 'Google Doodle')]
# [('property', 'http://www.wikidata.org/prop/direct/P4665'), ('propertyName', 'CineMagia title ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P9191'), ('propertyName', 'letterer')]
# [('property', 'http://www.wikidata.org/prop/direct/P2000'), ('propertyName', 'CPDL ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2689'), ('propertyName', 'BARTOC ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7988'), ('propertyName', 'Clavis Patrum Graecorum ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6398'), ('propertyName', 'iTunes movie ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P9281'), ('propertyName', 'Encyclopedia of Greater Philadelphia ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2596'), ('propertyName', 'culture')]
# [('property', 'http://www.wikidata.org/prop/direct/P4656'), ('propertyName', 'Wikimedia import URL')]
# [('property', 'http://www.wikidata.org/prop/direct/P6123'), ('propertyName', 'B3Kat dataset ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7140'), ('propertyName', 'München Wiki article ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P947'), ('propertyName', 'RSL ID (person)')]
# [('property', 'http://www.wikidata.org/prop/direct/P1640'), ('propertyName', 'curator')]
# [('property', 'http://www.wikidata.org/prop/direct/P6949'), ('propertyName', 'announcement date')]
# [('property', 'http://www.wikidata.org/prop/direct/P1448'), ('propertyName', 'official name')]
# [('property', 'http://www.wikidata.org/prop/direct/P5604'), ('propertyName', 'archINFORM keyword ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P8605'), ('propertyName', 'Linked Open Data Cloud identifier')]
# [('property', 'http://www.wikidata.org/prop/direct/P9272'), ('propertyName', 'DeCS ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7886'), ('propertyName', 'Media Arts Database ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5290'), ('propertyName', 'Redump.org ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P740'), ('propertyName', 'location of formation')]
# [('property', 'http://www.wikidata.org/prop/direct/P1801'), ('propertyName', 'commemorative plaque image')]
# [('property', 'http://www.wikidata.org/prop/direct/P2031'), ('propertyName', 'work period (start)')]
# [('property', 'http://www.wikidata.org/prop/direct/P6221'), ('propertyName', 'NooSFere story ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1441'), ('propertyName', 'present in work')]
# [('property', 'http://www.wikidata.org/prop/direct/P6283'), ('propertyName', 'MNopedia ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5570'), ('propertyName', 'NooSFere author ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2014'), ('propertyName', 'Museum of Modern Art work ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P607'), ('propertyName', 'conflict')]
# [('property', 'http://www.wikidata.org/prop/direct/P8332'), ('propertyName', 'Dansk litteraturs historie ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2880'), ('propertyName', 'NIOSHTIC-2 ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2883'), ('propertyName', 'HKMDB film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3861'), ('propertyName', 'App Store app ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3784'), ('propertyName', 'CiteSeerX article ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2381'), ('propertyName', 'Academic Tree ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7864'), ('propertyName', 'HAL article ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6323'), ('propertyName', 'Centre Pompidou ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P8791'), ('propertyName', 'digitised by')]
# [('property', 'http://www.wikidata.org/prop/direct/P818'), ('propertyName', 'arXiv ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P9016'), ('propertyName', 'Medieval Manuscripts in Oxford Libraries work ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4844'), ('propertyName', 'research intervention')]
# [('property', 'http://www.wikidata.org/prop/direct/P5199'), ('propertyName', 'British Library system number')]
# [('property', 'http://www.wikidata.org/prop/direct/P1779'), ('propertyName', 'possible creator')]
# [('property', 'http://www.wikidata.org/prop/direct/P3836'), ('propertyName', 'Pinterest username')]
# [('property', 'http://www.wikidata.org/prop/direct/P4444'), ('propertyName', 'reward')]
# [('property', 'http://www.wikidata.org/prop/direct/P3479'), ('propertyName', 'Omni topic ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3987'), ('propertyName', 'SHARE Catalogue author ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1092'), ('propertyName', 'total produced')]
# [('property', 'http://www.wikidata.org/prop/direct/P1190'), ('propertyName', 'Universal Decimal Classification')]
# [('property', 'http://www.wikidata.org/prop/direct/P1196'), ('propertyName', 'manner of death')]
# [('property', 'http://www.wikidata.org/prop/direct/P3788'), ('propertyName', 'BNMM authority ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4459'), ('propertyName', 'Spanish Biographical Dictionary ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P509'), ('propertyName', 'cause of death')]
# [('property', 'http://www.wikidata.org/prop/direct/P2558'), ('propertyName', 'autores.uy ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4158'), ('propertyName', 'autores.ar ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1659'), ('propertyName', 'see also')]
# [('property', 'http://www.wikidata.org/prop/direct/P8729'), ('propertyName', 'AniList anime ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7507'), ('propertyName', 'Ben Yehuda author ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4953'), ('propertyName', 'Library of Congress Genre/Form Terms ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2899'), ('propertyName', 'minimum age')]
# [('property', 'http://www.wikidata.org/prop/direct/P8569'), ('propertyName', 'YIVO Encyclopedia of Jews in Eastern Europe ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6954'), ('propertyName', 'online access status')]
# [('property', 'http://www.wikidata.org/prop/direct/P7991'), ('propertyName', 'Mirabile title ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6494'), ('propertyName', 'ISTC No.')]
# [('property', 'http://www.wikidata.org/prop/direct/P3919'), ('propertyName', 'contributed to creative work')]
# [('property', 'http://www.wikidata.org/prop/direct/P3184'), ('propertyName', 'Czech National Bibliography book ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P461'), ('propertyName', 'opposite of')]
# [('property', 'http://www.wikidata.org/prop/direct/P1143'), ('propertyName', 'BN (Argentine) editions')]
# [('property', 'http://www.wikidata.org/prop/direct/P4745'), ('propertyName', 'is proceedings from')]
# [('property', 'http://www.wikidata.org/prop/direct/P9586'), ('propertyName', 'Apple TV movie ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1326'), ('propertyName', 'latest date')]
# [('property', 'http://www.wikidata.org/prop/direct/P2878'), ('propertyName', 'Minitel code')]
# [('property', 'http://www.wikidata.org/prop/direct/P960'), ('propertyName', 'Tropicos ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4613'), ('propertyName', 'Encyclopedia of Modern Ukraine ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3575'), ('propertyName', 'data size')]
# [('property', 'http://www.wikidata.org/prop/direct/P344'), ('propertyName', 'director of photography')]
# [('property', 'http://www.wikidata.org/prop/direct/P4746'), ('propertyName', 'Elhuyar ZTH ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4970'), ('propertyName', 'alternate names')]
# [('property', 'http://www.wikidata.org/prop/direct/P2567'), ('propertyName', 'amended by')]
# [('property', 'http://www.wikidata.org/prop/direct/P8752'), ('propertyName', 'Kramerius of Moravian Library UUID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2189'), ('propertyName', 'BiblioNet publisher ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1451'), ('propertyName', 'motto text')]
# [('property', 'http://www.wikidata.org/prop/direct/P3383'), ('propertyName', 'film poster')]
# [('property', 'http://www.wikidata.org/prop/direct/P706'), ('propertyName', 'located in/on physical feature')]
# [('property', 'http://www.wikidata.org/prop/direct/P7388'), ('propertyName', 'Great Encyclopedia of Navarre ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P870'), ('propertyName', 'instrumentation')]
# [('property', 'http://www.wikidata.org/prop/direct/P710'), ('propertyName', 'participant')]
# [('property', 'http://www.wikidata.org/prop/direct/P9907'), ('propertyName', 'swisscovery edition ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5315'), ('propertyName', 'BioStor work ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P8903'), ('propertyName', 'HAL journal ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4730'), ('propertyName', 'Mir@bel journal ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P8237'), ('propertyName', 'LiederNet text ID')]
# 876

# %%
#Return all written works with author Paul Auster and their genre
queryString = """
SELECT distinct ?title ?genre
WHERE { 

# ?writtenWork wdt:P31 wd:Q47461344.
# ?writtenWork wdt:P50 wd:Q214642.
# ?writtenWork wdt:P1476 ?title.
# ?writtenWork wdt:P136 ?genreUri.
# ?genreUri <http://schema.org/name> ?genre.

} 
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('title', 'The Invention of Solitude'), ('genre', 'memoir')]
# [('title', 'Leviathan'), ('genre', 'crime novel')]
# [('title', 'The Invention of Solitude'), ('genre', 'autobiography')]
# [('title', 'Invisible'), ('genre', 'novel')]
# [('title', 'Timbuktu'), ('genre', 'novel')]
# [('title', 'Oracle Night'), ('genre', 'novel')]
# [('title', 'Travels in the Scriptorium'), ('genre', 'novel')]
# [('title', 'The Music of Chance'), ('genre', 'novel')]
# [('title', 'Mr. Vertigo'), ('genre', 'novel')]
# [('title', 'Sunset Park'), ('genre', 'novel')]
# [('title', 'The Brooklyn Follies'), ('genre', 'novel')]
# [('title', 'The New York Trilogy'), ('genre', 'novel')]
# [('title', 'The Book of Illusions'), ('genre', 'novel')]
# [('title', 'Leviathan'), ('genre', 'detective fiction')]
# [('title', 'In the Country of Last Things'), ('genre', 'epistolary novel')]
# [('title', 'In the Country of Last Things'), ('genre', 'science fiction novel')]
# [('title', 'Timbuktu'), ('genre', 'novella')]
# [('title', 'In the Country of Last Things'), ('genre', 'dystopian novel')]
# [('title', 'The New York Trilogy'), ('genre', 'mystery fiction')]
# [('title', 'The Music of Chance'), ('genre', 'hardboiled')]
# [('title', 'Leviathan'), ('genre', 'hardboiled')]
# 21

# %%
#Return all written works with author Paul Auster, their genre and "published in" property
queryString = """
SELECT distinct ?title ?genre ?publishedDate
WHERE { 

# ?writtenWork wdt:P31 wd:Q47461344.
# ?writtenWork wdt:P50 wd:Q214642.
# ?writtenWork wdt:P1476 ?title.
# ?writtenWork wdt:P136 ?genreUri.
# ?genreUri <http://schema.org/name> ?genre.
# ?writtenWork wdt:P1433 ?publishedDate

} 
"""

print("Results")
run_query(queryString)
# Out:
# Results
# Empty
# 0

# %%
#Return all written works with author Paul Auster, their genre and "production date" property
queryString = """
SELECT distinct ?title ?genre ?productionDate
WHERE { 

# ?writtenWork wdt:P31 wd:Q47461344.
# ?writtenWork wdt:P50 wd:Q214642.
# ?writtenWork wdt:P1476 ?title.
# ?writtenWork wdt:P136 ?genreUri.
# ?genreUri <http://schema.org/name> ?genre.
# ?writtenWork wdt:P2754 ?productionDate

} 
"""

print("Results")
run_query(queryString)
# Out:
# Results
# Empty
# 0

# %%
#Return all written works with author Paul Auster, their genre and "publication date" property
queryString = """
SELECT distinct ?title ?genre ?publicationDate
WHERE { 

# ?writtenWork wdt:P31 wd:Q47461344.
# ?writtenWork wdt:P50 wd:Q214642.
# ?writtenWork wdt:P1476 ?title.
# ?writtenWork wdt:P136 ?genreUri.
# ?genreUri <http://schema.org/name> ?genre.
# ?writtenWork wdt:P577 ?publicationDate

} 
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('title', 'Leviathan'), ('genre', 'crime novel'), ('publicationDate', '1992-01-01T00:00:00Z')]
# [('title', 'The Music of Chance'), ('genre', 'novel'), ('publicationDate', '1990-01-01T00:00:00Z')]
# [('title', 'Oracle Night'), ('genre', 'novel'), ('publicationDate', '2003-01-01T00:00:00Z')]
# [('title', 'Travels in the Scriptorium'), ('genre', 'novel'), ('publicationDate', '2006-01-01T00:00:00Z')]
# [('title', 'Timbuktu'), ('genre', 'novel'), ('publicationDate', '1999-05-01T00:00:00Z')]
# [('title', 'Invisible'), ('genre', 'novel'), ('publicationDate', '2009-01-01T00:00:00Z')]
# [('title', 'Mr. Vertigo'), ('genre', 'novel'), ('publicationDate', '1994-04-05T00:00:00Z')]
# [('title', 'Sunset Park'), ('genre', 'novel'), ('publicationDate', '2010-01-01T00:00:00Z')]
# [('title', 'The Brooklyn Follies'), ('genre', 'novel'), ('publicationDate', '2005-01-01T00:00:00Z')]
# [('title', 'The New York Trilogy'), ('genre', 'novel'), ('publicationDate', '1987-01-01T00:00:00Z')]
# [('title', 'The Book of Illusions'), ('genre', 'novel'), ('publicationDate', '2002-01-01T00:00:00Z')]
# [('title', 'Leviathan'), ('genre', 'detective fiction'), ('publicationDate', '1992-01-01T00:00:00Z')]
# [('title', 'In the Country of Last Things'), ('genre', 'epistolary novel'), ('publicationDate', '1987-01-01T00:00:00Z')]
# [('title', 'In the Country of Last Things'), ('genre', 'science fiction novel'), ('publicationDate', '1987-01-01T00:00:00Z')]
# [('title', 'Timbuktu'), ('genre', 'novella'), ('publicationDate', '1999-05-01T00:00:00Z')]
# [('title', 'In the Country of Last Things'), ('genre', 'dystopian novel'), ('publicationDate', '1987-01-01T00:00:00Z')]
# [('title', 'The New York Trilogy'), ('genre', 'mystery fiction'), ('publicationDate', '1987-01-01T00:00:00Z')]
# [('title', 'The Music of Chance'), ('genre', 'hardboiled'), ('publicationDate', '1990-01-01T00:00:00Z')]
# [('title', 'Leviathan'), ('genre', 'hardboiled'), ('publicationDate', '1992-01-01T00:00:00Z')]
# 19

# %%
#Return all the books (with publishing date and genre) published by the two authors
queryString = """
SELECT distinct ?author ?title ?genre ?publicationDate
WHERE { 
    {
        # ?writtenWork wdt:P31 wd:Q47461344.
        # ?writtenWork wdt:P50 wd:Q214642.

        # ?writtenWork wdt:P1476 ?title.

        wd:Q214642 wdt:P1559 ?author.

        # ?writtenWork wdt:P136 ?genreUri.
        # ?genreUri <http://schema.org/name> ?genre.

        # ?writtenWork wdt:P577 ?pubDate.
        BIND(CONCAT(STR(MONTH(?pubDate)),"/",STR(DAY(?pubDate)),"/",STR(YEAR(?pubDate))) AS ?publicationDate)
    }
    UNION
    {
        # ?writtenWork wdt:P31 wd:Q47461344.
        # ?writtenWork wdt:P50 wd:Q190379.

        # ?writtenWork wdt:P1476 ?title.

        wd:Q190379 wdt:P1559 ?author.

        # ?writtenWork wdt:P136 ?genreUri.
        # ?genreUri <http://schema.org/name> ?genre.

        # ?writtenWork wdt:P577 ?pubDate.
        BIND(CONCAT(STR(MONTH(?pubDate)),"/",STR(DAY(?pubDate)),"/",STR(YEAR(?pubDate))) AS ?publicationDate)
    }

} 
ORDER BY ASC (?author)
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('author', 'Ian McEwan'), ('title', 'The Child in Time'), ('genre', 'novel'), ('publicationDate', '1/1/1987')]
# [('author', 'Ian McEwan'), ('title', 'The Cement Garden'), ('genre', 'novel'), ('publicationDate', '1/1/1978')]
# [('author', 'Ian McEwan'), ('title', 'Enduring Love'), ('genre', 'novel'), ('publicationDate', '1/1/1997')]
# [('author', 'Ian McEwan'), ('title', 'Black Dogs'), ('genre', 'novel'), ('publicationDate', '7/1/1992')]
# [('author', 'Ian McEwan'), ('title', 'Saturday'), ('genre', 'novel'), ('publicationDate', '1/1/2005')]
# [('author', 'Ian McEwan'), ('title', 'On Chesil Beach'), ('genre', 'novel'), ('publicationDate', '1/1/2007')]
# [('author', 'Ian McEwan'), ('title', 'Sweet Tooth'), ('genre', 'novel'), ('publicationDate', '1/1/2012')]
# [('author', 'Ian McEwan'), ('title', 'Amsterdam'), ('genre', 'novel'), ('publicationDate', '12/1/1998')]
# [('author', 'Ian McEwan'), ('title', 'Solar'), ('genre', 'novel'), ('publicationDate', '3/18/2010')]
# [('author', 'Ian McEwan'), ('title', 'Atonement'), ('genre', 'novel'), ('publicationDate', '1/1/2001')]
# [('author', 'Ian McEwan'), ('title', 'The Comfort of Strangers'), ('genre', 'novel'), ('publicationDate', '1/1/1981')]
# [('author', 'Paul Auster'), ('title', 'Sunset Park'), ('genre', 'novel'), ('publicationDate', '1/1/2010')]
# [('author', 'Paul Auster'), ('title', 'In the Country of Last Things'), ('genre', 'dystopian novel'), ('publicationDate', '1/1/1987')]
# [('author', 'Paul Auster'), ('title', 'Travels in the Scriptorium'), ('genre', 'novel'), ('publicationDate', '1/1/2006')]
# [('author', 'Paul Auster'), ('title', 'Leviathan'), ('genre', 'detective fiction'), ('publicationDate', '1/1/1992')]
# [('author', 'Paul Auster'), ('title', 'The Music of Chance'), ('genre', 'novel'), ('publicationDate', '1/1/1990')]
# [('author', 'Paul Auster'), ('title', 'In the Country of Last Things'), ('genre', 'science fiction novel'), ('publicationDate', '1/1/1987')]
# [('author', 'Paul Auster'), ('title', 'Invisible'), ('genre', 'novel'), ('publicationDate', '1/1/2009')]
# [('author', 'Paul Auster'), ('title', 'The Music of Chance'), ('genre', 'hardboiled'), ('publicationDate', '1/1/1990')]
# [('author', 'Paul Auster'), ('title', 'The New York Trilogy'), ('genre', 'novel'), ('publicationDate', '1/1/1987')]
# [('author', 'Paul Auster'), ('title', 'Leviathan'), ('genre', 'crime novel'), ('publicationDate', '1/1/1992')]
# [('author', 'Paul Auster'), ('title', 'In the Country of Last Things'), ('genre', 'epistolary novel'), ('publicationDate', '1/1/1987')]
# [('author', 'Paul Auster'), ('title', 'Timbuktu'), ('genre', 'novel'), ('publicationDate', '5/1/1999')]
# [('author', 'Paul Auster'), ('title', 'The New York Trilogy'), ('genre', 'mystery fiction'), ('publicationDate', '1/1/1987')]
# [('author', 'Paul Auster'), ('title', 'The Brooklyn Follies'), ('genre', 'novel'), ('publicationDate', '1/1/2005')]
# [('author', 'Paul Auster'), ('title', 'Leviathan'), ('genre', 'hardboiled'), ('publicationDate', '1/1/1992')]
# [('author', 'Paul Auster'), ('title', 'Mr. Vertigo'), ('genre', 'novel'), ('publicationDate', '4/5/1994')]
# [('author', 'Paul Auster'), ('title', 'Timbuktu'), ('genre', 'novella'), ('publicationDate', '5/1/1999')]
# [('author', 'Paul Auster'), ('title', 'Oracle Night'), ('genre', 'novel'), ('publicationDate', '1/1/2003')]
# [('author', 'Paul Auster'), ('title', 'The Book of Illusions'), ('genre', 'novel'), ('publicationDate', '1/1/2002')]
# 30

# %% [markdown]
# #### Point 1 Finish
# DESCRIPTION:
# I started by checking the nodes connected to Paul Auster and their predicates.
# After have found the class "writtenWork" wd:Q47461344 I check both objects and predicates related to a general instance of this class but i was not satisfied.
# Then i discover the class "notableWork" wd:Q214642 and i tried to connect it to Paul Auster but the result didn't convice me.
# So i restarted from the class "book" wd:Q571 previously found and i discover that "writtenWork" is a superclass of "book" so i decided to check the predicates that connect Paul Auster to "writtenWork" and viceversa.
# After discoverign the predicate "author" wdt:P50 i performed some queries to understand how to return all written Works s.t. Paul Auster is author along with pub. date, title and genre.
# Then i took the union of the results considering both authors.
# I decided to use the class "writtenWork" insted of "book" because i was not sure about how wikidata identies a book. I could be that some short novel written by the autor is considered a book for some people and for others not.
#
# RESULT:
# Is it possible to see that Paul Auster has published more books than Ian McEwan, and that both authors worked in the same period more or less.

# %% [markdown]
# #### Point 2a Start

# %%
#Did the authors published a book in the same year?
queryString = """
SELECT *
WHERE{
    
    {
        SELECT ?pubDatePaul
        WHERE { 
            # ?writtenWork wdt:P31 wd:Q47461344.
            # ?writtenWork wdt:P50 wd:Q214642.

            # ?writtenWork wdt:P577 ?pubDatePaul.

        }
    }
    {
        SELECT ?pubDateIan
        WHERE { 
            # ?writtenWork wdt:P31 wd:Q47461344.
            # ?writtenWork wdt:P50 wd:Q190379.

            # ?writtenWork wdt:P577 ?pubDateIan.
            
        }
    }
    
    FILTER(?pubDatePaul = ?pubDateIan)
}

"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('pubDatePaul', '1987-01-01T00:00:00Z'), ('pubDateIan', '1987-01-01T00:00:00Z')]
# [('pubDatePaul', '1987-01-01T00:00:00Z'), ('pubDateIan', '1987-01-01T00:00:00Z')]
# [('pubDatePaul', '2005-01-01T00:00:00Z'), ('pubDateIan', '2005-01-01T00:00:00Z')]
# 3

# %% [markdown]
# #### Point 2a Finish
# RESULT: The answer is yes.

# %% [markdown]
# #### Point 2b Start

# %%
#What is the longest period without publishing a book for the two authors?
queryString = """
SELECT ?author (MAX(?period) AS ?maxPeriodInYear)
WHERE{
    {
        # ?writtenWork1 wdt:P31 wd:Q47461344.
        # ?writtenWork1 wdt:P50 wd:Q214642.

        # ?writtenWork1 wdt:P577 ?publicationDate1.

        wd:Q214642 wdt:P1559 ?author.


        # ?writtenWork2 wdt:P31 wd:Q47461344.
        # ?writtenWork2 wdt:P50 wd:Q214642.

        # ?writtenWork2 wdt:P577 ?publicationDate2.

        BIND(ABS(YEAR(?publicationDate1) - YEAR(?publicationDate2)) AS ?period)
    }
    UNION
    {
        # ?writtenWork1 wdt:P31 wd:Q47461344.
        # ?writtenWork1 wdt:P50 wd:Q190379.

        # ?writtenWork1 wdt:P577 ?publicationDate1.

        wd:Q190379 wdt:P1559 ?author.


        # ?writtenWork2 wdt:P31 wd:Q47461344.
        # ?writtenWork2 wdt:P50 wd:Q190379.

        # ?writtenWork2 wdt:P577 ?publicationDate2.

        BIND(ABS(YEAR(?publicationDate1) - YEAR(?publicationDate2)) AS ?period)
    }
    
}
GROUP BY (?author)
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('author', 'Paul Auster'), ('maxPeriodInYear', '23')]
# [('author', 'Ian McEwan'), ('maxPeriodInYear', '34')]
# 2

# %%
#What is the longest period without publishing a book for the two authors?
queryString = """

SELECT ?author ?maxPeriod
WHERE{

    {
        SELECT ?author (MAX(?minPeriod) AS ?maxPeriod)
        WHERE {
            wd:Q214642 wdt:P1559 ?author.
            {
                SELECT ?pubDatePaulYear (MIN(?period) AS ?minPeriod)
                WHERE { 
                    # ?writtenWork wdt:P31 wd:Q47461344.
                    # ?writtenWork wdt:P50 wd:Q214642. 

                    # ?writtenWork wdt:P577 ?pubDatePaul.

                    {
                        SELECT ?pubDatePaulIn
                        WHERE { 
                            # ?writtenWorkIn wdt:P31 wd:Q47461344.
                            # ?writtenWorkIn wdt:P50 wd:Q214642.

                            # ?writtenWorkIn wdt:P577 ?pubDatePaulIn. 
                        }
                    }

                    FILTER(?pubDatePaulIn != ?pubDatePaul)
                    BIND(YEAR(?pubDatePaul) AS ?pubDatePaulYear)
                    BIND(YEAR(?pubDatePaulIn) AS ?pubDatePaulYearIn)

                    BIND(ABS(?pubDatePaulYear - ?pubDatePaulYearIn) AS ?period)
                }
                GROUP BY ?pubDatePaulYear
            }
        }
    }
    UNION
    {
        SELECT ?author (MAX(?minPeriod) AS ?maxPeriod)
        WHERE {
            wd:Q190379 wdt:P1559 ?author.
            {
                SELECT ?pubDateIanYear (MIN(?period) AS ?minPeriod)
                WHERE { 
                    # ?writtenWork wdt:P31 wd:Q47461344.
                    # ?writtenWork wdt:P50 wd:Q190379. 

                    # ?writtenWork wdt:P577 ?pubDateIan.

                    {
                        SELECT ?pubDateIanIn
                        WHERE { 
                            # ?writtenWorkIn wdt:P31 wd:Q47461344.
                            # ?writtenWorkIn wdt:P50 wd:Q190379.

                            # ?writtenWorkIn wdt:P577 ?pubDateIanIn. 
                        }
                    }

                    FILTER(?pubDateIanIn != ?pubDateIan)
                    BIND(YEAR(?pubDateIan) AS ?pubDateIanYear)
                    BIND(YEAR(?pubDateIanIn) AS ?pubDateIanYearIn)

                    BIND(ABS(?pubDateIanYear - ?pubDateIanYearIn) AS ?period)
                }
                GROUP BY ?pubDateIanYear
            }
        }
    }




}


"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('author', 'Paul Auster'), ('maxPeriod', '3')]
# [('author', 'Ian McEwan'), ('maxPeriod', '5')]
# 2

# %% [markdown]
# #### Point 2b Finish
# DESCRIPTION: I tried with the first query but it was conceptually wrong.
#
# RESULT: Ian McEwan has a longer period without publishing a book.

# %% [markdown]
# #### Point 3 Start

# %%
#Return all properties of Creative work node
queryString = """
SELECT DISTINCT ?property ?propertyName
WHERE {

    # ?creativeWork wdt:P31 wd:Q17537576.
    # ?creativeWork ?property ?obj.
    # ?property <http://schema.org/name> ?propertyName.
}
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('property', 'http://www.wikidata.org/prop/direct/P2242'), ('propertyName', 'Florentine musea catalogue ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P304'), ('propertyName', 'page(s)')]
# [('property', 'http://www.wikidata.org/prop/direct/P478'), ('propertyName', 'volume')]
# [('property', 'http://www.wikidata.org/prop/direct/P2699'), ('propertyName', 'URL')]
# [('property', 'http://www.wikidata.org/prop/direct/P356'), ('propertyName', 'DOI')]
# [('property', 'http://www.wikidata.org/prop/direct/P6679'), ('propertyName', 'Encyklopedia Teatru Polskiego play ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7947'), ('propertyName', 'WeChangEd ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4003'), ('propertyName', 'Facebook page ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6721'), ('propertyName', 'K10plus PPN ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1219'), ('propertyName', 'Internet Broadway Database show ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1844'), ('propertyName', 'HathiTrust ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2008'), ('propertyName', 'IPNI publication ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2093'), ('propertyName', 'author name string')]
# [('property', 'http://www.wikidata.org/prop/direct/P2860'), ('propertyName', 'cites work')]
# [('property', 'http://www.wikidata.org/prop/direct/P4411'), ('propertyName', 'Quora username')]
# [('property', 'http://www.wikidata.org/prop/direct/P1065'), ('propertyName', 'archive URL')]
# [('property', 'http://www.wikidata.org/prop/direct/P1014'), ('propertyName', 'Art & Architecture Thesaurus ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1019'), ('propertyName', 'web feed URL')]
# [('property', 'http://www.wikidata.org/prop/direct/P1051'), ('propertyName', 'PSH ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1085'), ('propertyName', 'LibraryThing work ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1163'), ('propertyName', 'media type')]
# [('property', 'http://www.wikidata.org/prop/direct/P1195'), ('propertyName', 'file extension')]
# [('property', 'http://www.wikidata.org/prop/direct/P123'), ('propertyName', 'publisher')]
# [('property', 'http://www.wikidata.org/prop/direct/P1245'), ('propertyName', 'OmegaWiki Defined Meaning')]
# [('property', 'http://www.wikidata.org/prop/direct/P1256'), ('propertyName', 'Iconclass notation')]
# [('property', 'http://www.wikidata.org/prop/direct/P127'), ('propertyName', 'owned by')]
# [('property', 'http://www.wikidata.org/prop/direct/P1296'), ('propertyName', 'Gran Enciclopèdia Catalana ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P131'), ('propertyName', 'located in the administrative territorial entity')]
# [('property', 'http://www.wikidata.org/prop/direct/P1324'), ('propertyName', 'source code repository')]
# [('property', 'http://www.wikidata.org/prop/direct/P1343'), ('propertyName', 'described by source')]
# [('property', 'http://www.wikidata.org/prop/direct/P135'), ('propertyName', 'movement')]
# [('property', 'http://www.wikidata.org/prop/direct/P136'), ('propertyName', 'genre')]
# [('property', 'http://www.wikidata.org/prop/direct/P1401'), ('propertyName', 'bug tracking system')]
# [('property', 'http://www.wikidata.org/prop/direct/P1417'), ('propertyName', 'Encyclopædia Britannica Online ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1424'), ('propertyName', "topic's main template")]
# [('property', 'http://www.wikidata.org/prop/direct/P1434'), ('propertyName', 'takes place in fictional universe')]
# [('property', 'http://www.wikidata.org/prop/direct/P144'), ('propertyName', 'based on')]
# [('property', 'http://www.wikidata.org/prop/direct/P1462'), ('propertyName', 'standards body')]
# [('property', 'http://www.wikidata.org/prop/direct/P1476'), ('propertyName', 'title')]
# [('property', 'http://www.wikidata.org/prop/direct/P1482'), ('propertyName', 'Stack Exchange tag')]
# [('property', 'http://www.wikidata.org/prop/direct/P154'), ('propertyName', 'logo image')]
# [('property', 'http://www.wikidata.org/prop/direct/P155'), ('propertyName', 'follows')]
# [('property', 'http://www.wikidata.org/prop/direct/P156'), ('propertyName', 'followed by')]
# [('property', 'http://www.wikidata.org/prop/direct/P1581'), ('propertyName', 'official blog')]
# [('property', 'http://www.wikidata.org/prop/direct/P159'), ('propertyName', 'headquarters location')]
# [('property', 'http://www.wikidata.org/prop/direct/P162'), ('propertyName', 'producer')]
# [('property', 'http://www.wikidata.org/prop/direct/P166'), ('propertyName', 'award received')]
# [('property', 'http://www.wikidata.org/prop/direct/P1661'), ('propertyName', 'Alexa rank')]
# [('property', 'http://www.wikidata.org/prop/direct/P17'), ('propertyName', 'country')]
# [('property', 'http://www.wikidata.org/prop/direct/P170'), ('propertyName', 'creator')]
# [('property', 'http://www.wikidata.org/prop/direct/P1711'), ('propertyName', 'British Museum person or institution ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1729'), ('propertyName', 'AllMusic album ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P175'), ('propertyName', 'performer')]
# [('property', 'http://www.wikidata.org/prop/direct/P178'), ('propertyName', 'developer')]
# [('property', 'http://www.wikidata.org/prop/direct/P179'), ('propertyName', 'part of the series')]
# [('property', 'http://www.wikidata.org/prop/direct/P18'), ('propertyName', 'image')]
# [('property', 'http://www.wikidata.org/prop/direct/P180'), ('propertyName', 'depicts')]
# [('property', 'http://www.wikidata.org/prop/direct/P1813'), ('propertyName', 'short name')]
# [('property', 'http://www.wikidata.org/prop/direct/P186'), ('propertyName', 'made from material')]
# [('property', 'http://www.wikidata.org/prop/direct/P1881'), ('propertyName', 'list of characters')]
# [('property', 'http://www.wikidata.org/prop/direct/P1889'), ('propertyName', 'different from')]
# [('property', 'http://www.wikidata.org/prop/direct/P195'), ('propertyName', 'collection')]
# [('property', 'http://www.wikidata.org/prop/direct/P1954'), ('propertyName', 'Discogs master ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2002'), ('propertyName', 'Twitter username')]
# [('property', 'http://www.wikidata.org/prop/direct/P2003'), ('propertyName', 'Instagram username')]
# [('property', 'http://www.wikidata.org/prop/direct/P2013'), ('propertyName', 'Facebook ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2048'), ('propertyName', 'height')]
# [('property', 'http://www.wikidata.org/prop/direct/P2049'), ('propertyName', 'width')]
# [('property', 'http://www.wikidata.org/prop/direct/P214'), ('propertyName', 'VIAF ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P217'), ('propertyName', 'inventory number')]
# [('property', 'http://www.wikidata.org/prop/direct/P2184'), ('propertyName', 'history of topic')]
# [('property', 'http://www.wikidata.org/prop/direct/P227'), ('propertyName', 'GND ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2347'), ('propertyName', 'YSO ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2397'), ('propertyName', 'YouTube channel ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P243'), ('propertyName', 'OCLC control number')]
# [('property', 'http://www.wikidata.org/prop/direct/P244'), ('propertyName', 'Library of Congress authority ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2572'), ('propertyName', 'hashtag')]
# [('property', 'http://www.wikidata.org/prop/direct/P2581'), ('propertyName', 'BabelNet ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2596'), ('propertyName', 'culture')]
# [('property', 'http://www.wikidata.org/prop/direct/P2635'), ('propertyName', 'number of parts of this work')]
# [('property', 'http://www.wikidata.org/prop/direct/P264'), ('propertyName', 'record label')]
# [('property', 'http://www.wikidata.org/prop/direct/P2671'), ('propertyName', 'Google Knowledge Graph ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P268'), ('propertyName', 'Bibliothèque nationale de France ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P269'), ('propertyName', 'IdRef ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P272'), ('propertyName', 'production company')]
# [('property', 'http://www.wikidata.org/prop/direct/P275'), ('propertyName', 'copyright license')]
# [('property', 'http://www.wikidata.org/prop/direct/P276'), ('propertyName', 'location')]
# [('property', 'http://www.wikidata.org/prop/direct/P279'), ('propertyName', 'subclass of')]
# [('property', 'http://www.wikidata.org/prop/direct/P2888'), ('propertyName', 'exact match')]
# [('property', 'http://www.wikidata.org/prop/direct/P291'), ('propertyName', 'place of publication')]
# [('property', 'http://www.wikidata.org/prop/direct/P2910'), ('propertyName', 'icon')]
# [('property', 'http://www.wikidata.org/prop/direct/P2924'), ('propertyName', 'Great Russian Encyclopedia Online ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3095'), ('propertyName', 'practiced by')]
# [('property', 'http://www.wikidata.org/prop/direct/P31'), ('propertyName', 'instance of')]
# [('property', 'http://www.wikidata.org/prop/direct/P3134'), ('propertyName', 'TripAdvisor ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3219'), ('propertyName', 'Encyclopædia Universalis ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3222'), ('propertyName', 'NE.se ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3235'), ('propertyName', 'PhilPapers topic')]
# [('property', 'http://www.wikidata.org/prop/direct/P3381'), ('propertyName', 'File Format Wiki page ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3417'), ('propertyName', 'Quora topic ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P349'), ('propertyName', 'National Diet Library ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3553'), ('propertyName', 'Zhihu topic ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P361'), ('propertyName', 'part of')]
# [('property', 'http://www.wikidata.org/prop/direct/P366'), ('propertyName', 'use')]
# [('property', 'http://www.wikidata.org/prop/direct/P373'), ('propertyName', 'Commons category')]
# [('property', 'http://www.wikidata.org/prop/direct/P3827'), ('propertyName', 'JSTOR topic ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3836'), ('propertyName', 'Pinterest username')]
# [('property', 'http://www.wikidata.org/prop/direct/P3847'), ('propertyName', 'Open Library subject ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3916'), ('propertyName', 'UNESCO Thesaurus ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3964'), ('propertyName', 'BDCYL authority ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3984'), ('propertyName', 'subreddit')]
# [('property', 'http://www.wikidata.org/prop/direct/P400'), ('propertyName', 'platform')]
# [('property', 'http://www.wikidata.org/prop/direct/P407'), ('propertyName', 'language of work or name')]
# [('property', 'http://www.wikidata.org/prop/direct/P4212'), ('propertyName', 'PACTOLS thesaurus ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4264'), ('propertyName', 'LinkedIn company ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4342'), ('propertyName', 'Store norske leksikon ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P435'), ('propertyName', 'MusicBrainz work ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P436'), ('propertyName', 'MusicBrainz release group ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P460'), ('propertyName', 'said to be the same as')]
# [('property', 'http://www.wikidata.org/prop/direct/P4839'), ('propertyName', 'Wolfram Language entity code')]
# [('property', 'http://www.wikidata.org/prop/direct/P495'), ('propertyName', 'country of origin')]
# [('property', 'http://www.wikidata.org/prop/direct/P4969'), ('propertyName', 'derivative work')]
# [('property', 'http://www.wikidata.org/prop/direct/P50'), ('propertyName', 'author')]
# [('property', 'http://www.wikidata.org/prop/direct/P5008'), ('propertyName', 'on focus list of Wikimedia project')]
# [('property', 'http://www.wikidata.org/prop/direct/P503'), ('propertyName', 'ISO standard')]
# [('property', 'http://www.wikidata.org/prop/direct/P508'), ('propertyName', 'BNCF Thesaurus ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5088'), ('propertyName', 'Internet Encyclopedia of Philosophy ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5229'), ('propertyName', 'Carnegie Hall work ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P527'), ('propertyName', 'has part')]
# [('property', 'http://www.wikidata.org/prop/direct/P528'), ('propertyName', 'catalog code')]
# [('property', 'http://www.wikidata.org/prop/direct/P5331'), ('propertyName', 'OCLC work ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5398'), ('propertyName', 'TDKIV term ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P553'), ('propertyName', 'website account on')]
# [('property', 'http://www.wikidata.org/prop/direct/P571'), ('propertyName', 'inception')]
# [('property', 'http://www.wikidata.org/prop/direct/P577'), ('propertyName', 'publication date')]
# [('property', 'http://www.wikidata.org/prop/direct/P58'), ('propertyName', 'screenwriter')]
# [('property', 'http://www.wikidata.org/prop/direct/P580'), ('propertyName', 'start time')]
# [('property', 'http://www.wikidata.org/prop/direct/P582'), ('propertyName', 'end time')]
# [('property', 'http://www.wikidata.org/prop/direct/P6058'), ('propertyName', 'Larousse ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P61'), ('propertyName', 'discoverer or inventor')]
# [('property', 'http://www.wikidata.org/prop/direct/P6216'), ('propertyName', 'copyright status')]
# [('property', 'http://www.wikidata.org/prop/direct/P6366'), ('propertyName', 'Microsoft Academic ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P646'), ('propertyName', 'Freebase ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P648'), ('propertyName', 'Open Library ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6573'), ('propertyName', 'Klexikon article ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6611'), ('propertyName', 'Semantic Scholar topic ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6706'), ('propertyName', 'De Agostini ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P674'), ('propertyName', 'characters')]
# [('property', 'http://www.wikidata.org/prop/direct/P6857'), ('propertyName', 'JIS standard')]
# [('property', 'http://www.wikidata.org/prop/direct/P7033'), ('propertyName', 'Australian Educational Vocabulary ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P724'), ('propertyName', 'Internet Archive ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7293'), ('propertyName', 'PLWABN ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7314'), ('propertyName', 'TDV İslam Ansiklopedisi ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7369'), ('propertyName', 'National Library of Chile ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P747'), ('propertyName', 'has edition or translation')]
# [('property', 'http://www.wikidata.org/prop/direct/P7818'), ('propertyName', 'French Vikidia ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7822'), ('propertyName', 'Italian Vikidia ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7937'), ('propertyName', 'form of creative work')]
# [('property', 'http://www.wikidata.org/prop/direct/P7982'), ('propertyName', 'Hrvatska enciklopedija ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7993'), ('propertyName', "Treccani's Dizionario di Filosofia ID")]
# [('property', 'http://www.wikidata.org/prop/direct/P8179'), ('propertyName', 'Canadiana NCF ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P8189'), ('propertyName', 'National Library of Israel J9U ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P8205'), ('propertyName', 'Mozilla Developer Network article')]
# [('property', 'http://www.wikidata.org/prop/direct/P826'), ('propertyName', 'tonality')]
# [('property', 'http://www.wikidata.org/prop/direct/P8383'), ('propertyName', 'Goodreads work ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P839'), ('propertyName', 'IMSLP ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P840'), ('propertyName', 'narrative location')]
# [('property', 'http://www.wikidata.org/prop/direct/P8406'), ('propertyName', 'Grove Art Online ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P8408'), ('propertyName', 'KBpedia ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P8411'), ('propertyName', 'set in environment')]
# [('property', 'http://www.wikidata.org/prop/direct/P856'), ('propertyName', 'official website')]
# [('property', 'http://www.wikidata.org/prop/direct/P8569'), ('propertyName', 'YIVO Encyclopedia of Jews in Eastern Europe ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P86'), ('propertyName', 'composer')]
# [('property', 'http://www.wikidata.org/prop/direct/P8672'), ('propertyName', 'Twitter topic ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P8814'), ('propertyName', 'WordNet 3.1 Synset ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P8885'), ('propertyName', 'Namuwiki ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P906'), ('propertyName', 'SELIBR ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P910'), ('propertyName', "topic's main category")]
# [('property', 'http://www.wikidata.org/prop/direct/P9100'), ('propertyName', 'GitHub topic')]
# [('property', 'http://www.wikidata.org/prop/direct/P921'), ('propertyName', 'main subject')]
# [('property', 'http://www.wikidata.org/prop/direct/P935'), ('propertyName', 'Commons gallery')]
# [('property', 'http://www.wikidata.org/prop/direct/P94'), ('propertyName', 'coat of arms image')]
# [('property', 'http://www.wikidata.org/prop/direct/P949'), ('propertyName', 'National Library of Israel ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P950'), ('propertyName', 'Biblioteca Nacional de España ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P953'), ('propertyName', 'full work available at URL')]
# [('property', 'http://www.wikidata.org/prop/direct/P9545'), ('propertyName', 'Encyclopedia of China Online Database ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P973'), ('propertyName', 'described at URL')]
# [('property', 'http://www.wikidata.org/prop/direct/P98'), ('propertyName', 'editor')]
# [('property', 'http://www.wikidata.org/prop/direct/P996'), ('propertyName', 'document file on Wikimedia Commons')]
# [('property', 'http://www.wikidata.org/prop/direct/P1433'), ('propertyName', 'published in')]
# [('property', 'http://www.wikidata.org/prop/direct/P1191'), ('propertyName', 'date of first performance')]
# [('property', 'http://www.wikidata.org/prop/direct/P1680'), ('propertyName', 'subtitle')]
# [('property', 'http://www.wikidata.org/prop/direct/P1994'), ('propertyName', 'AllMusic composition ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2014'), ('propertyName', 'Museum of Modern Art work ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P212'), ('propertyName', 'ISBN-13')]
# [('property', 'http://www.wikidata.org/prop/direct/P4258'), ('propertyName', 'Gallica ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4647'), ('propertyName', 'location of first performance')]
# [('property', 'http://www.wikidata.org/prop/direct/P6175'), ('propertyName', 'Bitraga work ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P675'), ('propertyName', 'Google Books ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P736'), ('propertyName', 'cover art by')]
# [('property', 'http://www.wikidata.org/prop/direct/P8091'), ('propertyName', 'Archival Resource Key')]
# [('property', 'http://www.wikidata.org/prop/direct/P8359'), ('propertyName', 'Dewey Decimal Classification (works and editions)')]
# [('property', 'http://www.wikidata.org/prop/direct/P8360'), ('propertyName', 'Library of Congress Classification (works and editions)')]
# [('property', 'http://www.wikidata.org/prop/direct/P870'), ('propertyName', 'instrumentation')]
# [('property', 'http://www.wikidata.org/prop/direct/P957'), ('propertyName', 'ISBN-10')]
# [('property', 'http://www.wikidata.org/prop/direct/P433'), ('propertyName', 'issue')]
# [('property', 'http://www.wikidata.org/prop/direct/P2969'), ('propertyName', 'Goodreads version/edition ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P8070'), ('propertyName', 'ToposText work ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P8311'), ('propertyName', 'PHI Latin Texts work ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P8312'), ('propertyName', 'Musisque Deoque work ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3462'), ('propertyName', 'FAMA work ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2634'), ('propertyName', 'sitter')]
# [('property', 'http://www.wikidata.org/prop/direct/P1044'), ('propertyName', 'SWB editions')]
# [('property', 'http://www.wikidata.org/prop/direct/P4989'), ('propertyName', 'RKDlibrary ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P819'), ('propertyName', 'ADS bibcode')]
# [('property', 'http://www.wikidata.org/prop/direct/P6179'), ('propertyName', 'Dimensions Publication ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6979'), ('propertyName', 'SLNSW unpublished item ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P9270'), ('propertyName', 'ANSI/NISO standard ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P138'), ('propertyName', 'named after')]
# [('property', 'http://www.wikidata.org/prop/direct/P5986'), ('propertyName', 'Getty Iconography Authority ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2034'), ('propertyName', 'Project Gutenberg ebook ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6693'), ('propertyName', 'NGMDb Prod ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7234'), ('propertyName', 'Scribd item ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1809'), ('propertyName', 'choreographer')]
# [('property', 'http://www.wikidata.org/prop/direct/P4373'), ('propertyName', 'National Trust Collections ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P110'), ('propertyName', 'illustrator')]
# [('property', 'http://www.wikidata.org/prop/direct/P1104'), ('propertyName', 'number of pages')]
# [('property', 'http://www.wikidata.org/prop/direct/P1114'), ('propertyName', 'quantity')]
# [('property', 'http://www.wikidata.org/prop/direct/P2041'), ('propertyName', 'National Gallery of Victoria artist ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P236'), ('propertyName', 'ISSN')]
# [('property', 'http://www.wikidata.org/prop/direct/P364'), ('propertyName', 'original language of film or TV show')]
# [('property', 'http://www.wikidata.org/prop/direct/P409'), ('propertyName', 'Libraries Australia ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4215'), ('propertyName', 'nLab ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P51'), ('propertyName', 'audio')]
# [('property', 'http://www.wikidata.org/prop/direct/P585'), ('propertyName', 'point in time')]
# [('property', 'http://www.wikidata.org/prop/direct/P6379'), ('propertyName', 'has works in the collection')]
# [('property', 'http://www.wikidata.org/prop/direct/P691'), ('propertyName', 'NKCR AUT ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7363'), ('propertyName', 'ISSN-L')]
# [('property', 'http://www.wikidata.org/prop/direct/P767'), ('propertyName', 'contributor to the creative work or subject')]
# [('property', 'http://www.wikidata.org/prop/direct/P7844'), ('propertyName', 'Joconde object type ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P8514'), ('propertyName', 'TOPCMB ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P941'), ('propertyName', 'inspired by')]
# [('property', 'http://www.wikidata.org/prop/direct/P1071'), ('propertyName', 'location of creation')]
# [('property', 'http://www.wikidata.org/prop/direct/P1274'), ('propertyName', 'ISFDB title ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3959'), ('propertyName', 'NNL item ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P629'), ('propertyName', 'edition or translation of')]
# [('property', 'http://www.wikidata.org/prop/direct/P3174'), ('propertyName', 'art director')]
# [('property', 'http://www.wikidata.org/prop/direct/P3976'), ('propertyName', 'BVMC work ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4701'), ('propertyName', 'Google Arts & Culture asset ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7037'), ('propertyName', 'COURAGE ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1726'), ('propertyName', 'Florentine musea Inventario 1890 ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4506'), ('propertyName', 'Formal Public Identifier')]
# [('property', 'http://www.wikidata.org/prop/direct/P1015'), ('propertyName', 'NORAF ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1299'), ('propertyName', 'depicted by')]
# [('property', 'http://www.wikidata.org/prop/direct/P2079'), ('propertyName', 'fabrication method')]
# [('property', 'http://www.wikidata.org/prop/direct/P2163'), ('propertyName', 'FAST ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3040'), ('propertyName', 'SoundCloud ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P371'), ('propertyName', 'presenter')]
# [('property', 'http://www.wikidata.org/prop/direct/P437'), ('propertyName', 'distribution format')]
# [('property', 'http://www.wikidata.org/prop/direct/P5749'), ('propertyName', 'Amazon Standard Identification Number')]
# [('property', 'http://www.wikidata.org/prop/direct/P608'), ('propertyName', 'exhibition history')]
# [('property', 'http://www.wikidata.org/prop/direct/P8687'), ('propertyName', 'social media followers')]
# [('property', 'http://www.wikidata.org/prop/direct/P3899'), ('propertyName', 'Medium username')]
# [('property', 'http://www.wikidata.org/prop/direct/P4175'), ('propertyName', 'Patreon ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5792'), ('propertyName', 'NooSFere series ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P9024'), ('propertyName', 'Libsyn show ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4011'), ('propertyName', 'Semantic Scholar paper ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5587'), ('propertyName', 'Libris-URI')]
# [('property', 'http://www.wikidata.org/prop/direct/P8168'), ('propertyName', 'FactGrid item ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1182'), ('propertyName', 'LIBRIS editions')]
# [('property', 'http://www.wikidata.org/prop/direct/P5123'), ('propertyName', 'Swedish Literature Bank edition')]
# [('property', 'http://www.wikidata.org/prop/direct/P5059'), ('propertyName', 'modified version of')]
# [('property', 'http://www.wikidata.org/prop/direct/P6241'), ('propertyName', 'collection creator')]
# [('property', 'http://www.wikidata.org/prop/direct/P7487'), ('propertyName', 'Kinematoscope literary work ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1144'), ('propertyName', 'Library of Congress Control Number (LCCN) (bibliographic)')]
# [('property', 'http://www.wikidata.org/prop/direct/P1190'), ('propertyName', 'Universal Decimal Classification')]
# [('property', 'http://www.wikidata.org/prop/direct/P1922'), ('propertyName', 'first line')]
# [('property', 'http://www.wikidata.org/prop/direct/P2043'), ('propertyName', 'length')]
# [('property', 'http://www.wikidata.org/prop/direct/P2283'), ('propertyName', 'uses')]
# [('property', 'http://www.wikidata.org/prop/direct/P2670'), ('propertyName', 'has parts of the class')]
# [('property', 'http://www.wikidata.org/prop/direct/P393'), ('propertyName', 'edition number')]
# [('property', 'http://www.wikidata.org/prop/direct/P4801'), ('propertyName', 'LoC and MARC vocabularies ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5395'), ('propertyName', 'Canadian Encyclopedia article ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P859'), ('propertyName', 'sponsor')]
# [('property', 'http://www.wikidata.org/prop/direct/P989'), ('propertyName', 'spoken text audio')]
# [('property', 'http://www.wikidata.org/prop/direct/P3132'), ('propertyName', 'last line')]
# [('property', 'http://www.wikidata.org/prop/direct/P6877'), ('propertyName', 'MAHG ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2754'), ('propertyName', 'production date')]
# [('property', 'http://www.wikidata.org/prop/direct/P823'), ('propertyName', 'speaker')]
# [('property', 'http://www.wikidata.org/prop/direct/P4109'), ('propertyName', 'URN-NBN')]
# [('property', 'http://www.wikidata.org/prop/direct/P1273'), ('propertyName', 'CANTIC ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1957'), ('propertyName', 'Wikisource index page URL')]
# [('property', 'http://www.wikidata.org/prop/direct/P3241'), ('propertyName', 'Catholic Encyclopedia ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P487'), ('propertyName', 'Unicode character')]
# [('property', 'http://www.wikidata.org/prop/direct/P793'), ('propertyName', 'significant event')]
# [('property', 'http://www.wikidata.org/prop/direct/P4230'), ('propertyName', 'Sefaria ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P8248'), ('propertyName', 'Colon Classification')]
# [('property', 'http://www.wikidata.org/prop/direct/P9016'), ('propertyName', 'Medieval Manuscripts in Oxford Libraries work ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1225'), ('propertyName', 'U.S. National Archives Identifier')]
# [('property', 'http://www.wikidata.org/prop/direct/P1269'), ('propertyName', 'facet of')]
# [('property', 'http://www.wikidata.org/prop/direct/P1375'), ('propertyName', 'NSK ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1580'), ('propertyName', 'University of Barcelona authority ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P161'), ('propertyName', 'cast member')]
# [('property', 'http://www.wikidata.org/prop/direct/P2732'), ('propertyName', 'Persée author ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P57'), ('propertyName', 'director')]
# [('property', 'http://www.wikidata.org/prop/direct/P6870'), ('propertyName', 'Latvian National Encyclopedia Online ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P828'), ('propertyName', 'has cause')]
# [('property', 'http://www.wikidata.org/prop/direct/P88'), ('propertyName', 'commissioned by')]
# [('property', 'http://www.wikidata.org/prop/direct/P8294'), ('propertyName', 'AusStage work ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1025'), ('propertyName', 'SUDOC editions')]
# [('property', 'http://www.wikidata.org/prop/direct/P1817'), ('propertyName', 'addressee')]
# [('property', 'http://www.wikidata.org/prop/direct/P6224'), ('propertyName', 'level of description')]
# [('property', 'http://www.wikidata.org/prop/direct/P7328'), ('propertyName', 'amount cataloged')]
# [('property', 'http://www.wikidata.org/prop/direct/P6418'), ('propertyName', 'funk channel ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6761'), ('propertyName', 'NARA collection identifier')]
# [('property', 'http://www.wikidata.org/prop/direct/P4327'), ('propertyName', 'BHL bibliography ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P8324'), ('propertyName', 'funder')]
# [('property', 'http://www.wikidata.org/prop/direct/P960'), ('propertyName', 'Tropicos ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1739'), ('propertyName', 'CiNii book ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1242'), ('propertyName', 'Theatricalia play ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1149'), ('propertyName', 'Library of Congress Classification')]
# [('property', 'http://www.wikidata.org/prop/direct/P1669'), ('propertyName', 'Cultural Objects Names Authority ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P282'), ('propertyName', 'writing system')]
# [('property', 'http://www.wikidata.org/prop/direct/P3794'), ('propertyName', 'Dictionary of Sydney ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P641'), ('propertyName', 'sport')]
# [('property', 'http://www.wikidata.org/prop/direct/P406'), ('propertyName', 'soundtrack release')]
# [('property', 'http://www.wikidata.org/prop/direct/P4517'), ('propertyName', 'ctext work ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5833'), ('propertyName', 'Playbill production ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4956'), ('propertyName', 'BDH edition ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P8361'), ('propertyName', 'Universal Decimal Classification (works and editions)')]
# [('property', 'http://www.wikidata.org/prop/direct/P2386'), ('propertyName', 'diameter')]
# [('property', 'http://www.wikidata.org/prop/direct/P281'), ('propertyName', 'postal code')]
# [('property', 'http://www.wikidata.org/prop/direct/P4399'), ('propertyName', 'Itaú Cultural ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P575'), ('propertyName', 'time of discovery or invention')]
# [('property', 'http://www.wikidata.org/prop/direct/P9106'), ('propertyName', 'Oxford Classical Dictionary ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1877'), ('propertyName', 'after a work by')]
# [('property', 'http://www.wikidata.org/prop/direct/P7439'), ('propertyName', 'FantLab work ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3634'), ('propertyName', 'The Met object ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7908'), ('propertyName', 'Clavis Clavium ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P8163'), ('propertyName', 'Diels-Kranz ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7980'), ('propertyName', 'Clavis Patrum Latinorum ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7103'), ('propertyName', 'start of covered period')]
# [('property', 'http://www.wikidata.org/prop/direct/P7104'), ('propertyName', 'end of covered period')]
# [('property', 'http://www.wikidata.org/prop/direct/P1695'), ('propertyName', 'NLP ID (unique)')]
# [('property', 'http://www.wikidata.org/prop/direct/P6191'), ('propertyName', 'language style')]
# [('property', 'http://www.wikidata.org/prop/direct/P4625'), ('propertyName', 'Museum of Fine Arts, Boston object ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2936'), ('propertyName', 'language used')]
# [('property', 'http://www.wikidata.org/prop/direct/P4904'), ('propertyName', 'Tropicos publication ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1535'), ('propertyName', 'used by')]
# [('property', 'http://www.wikidata.org/prop/direct/P1705'), ('propertyName', 'native label')]
# [('property', 'http://www.wikidata.org/prop/direct/P2348'), ('propertyName', 'time period')]
# [('property', 'http://www.wikidata.org/prop/direct/P6228'), ('propertyName', 'RegiowikiAT ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P9286'), ('propertyName', 'Encyclopaedia Herder concept ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P968'), ('propertyName', 'email address')]
# [('property', 'http://www.wikidata.org/prop/direct/P1257'), ('propertyName', 'depicts Iconclass notation')]
# [('property', 'http://www.wikidata.org/prop/direct/P2623'), ('propertyName', 'MEK ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P101'), ('propertyName', 'field of work')]
# [('property', 'http://www.wikidata.org/prop/direct/P137'), ('propertyName', 'operator')]
# [('property', 'http://www.wikidata.org/prop/direct/P345'), ('propertyName', 'IMDb ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4983'), ('propertyName', 'TMDb TV series ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5981'), ('propertyName', 'Encyclopedia Virginia ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P750'), ('propertyName', 'distributed by')]
# [('property', 'http://www.wikidata.org/prop/direct/P3943'), ('propertyName', 'Tumblr username')]
# [('property', 'http://www.wikidata.org/prop/direct/P6467'), ('propertyName', 'Hulu series ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P9215'), ('propertyName', 'set during recurring event')]
# [('property', 'http://www.wikidata.org/prop/direct/P8791'), ('propertyName', 'digitised by')]
# [('property', 'http://www.wikidata.org/prop/direct/P5357'), ('propertyName', 'The Encyclopedia of Science Fiction ID')]
# 367

# %%
#Return all properties connecting "Creative work" object to "Written work" object
queryString = """
SELECT DISTINCT ?property ?propertyName
WHERE {

    # ?creativeWork wdt:P31 wd:Q17537576.
    # ?writtenWork wdt:P31 wd:Q47461344.
    # ?creativeWork ?property ?writtenWork.
    # ?property <http://schema.org/name> ?propertyName.
}
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('property', 'http://www.wikidata.org/prop/direct/P156'), ('propertyName', 'followed by')]
# [('property', 'http://www.wikidata.org/prop/direct/P921'), ('propertyName', 'main subject')]
# [('property', 'http://www.wikidata.org/prop/direct/P941'), ('propertyName', 'inspired by')]
# [('property', 'http://www.wikidata.org/prop/direct/P31'), ('propertyName', 'instance of')]
# [('property', 'http://www.wikidata.org/prop/direct/P527'), ('propertyName', 'has part')]
# [('property', 'http://www.wikidata.org/prop/direct/P747'), ('propertyName', 'has edition or translation')]
# [('property', 'http://www.wikidata.org/prop/direct/P361'), ('propertyName', 'part of')]
# [('property', 'http://www.wikidata.org/prop/direct/P155'), ('propertyName', 'follows')]
# [('property', 'http://www.wikidata.org/prop/direct/P1433'), ('propertyName', 'published in')]
# 9

# %%
#Return all properties connecting "Written work" object to "Creative work" object
queryString = """
SELECT DISTINCT ?property ?propertyName
WHERE {

    # ?creativeWork wdt:P31 wd:Q17537576.
    # ?writtenWork wdt:P31 wd:Q47461344.
    # ?writtenWork ?property ?creativeWork .
    # ?property <http://schema.org/name> ?propertyName.
}
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('property', 'http://www.wikidata.org/prop/direct/P155'), ('propertyName', 'follows')]
# [('property', 'http://www.wikidata.org/prop/direct/P179'), ('propertyName', 'part of the series')]
# [('property', 'http://www.wikidata.org/prop/direct/P361'), ('propertyName', 'part of')]
# [('property', 'http://www.wikidata.org/prop/direct/P527'), ('propertyName', 'has part')]
# [('property', 'http://www.wikidata.org/prop/direct/P921'), ('propertyName', 'main subject')]
# [('property', 'http://www.wikidata.org/prop/direct/P1433'), ('propertyName', 'published in')]
# [('property', 'http://www.wikidata.org/prop/direct/P629'), ('propertyName', 'edition or translation of')]
# [('property', 'http://www.wikidata.org/prop/direct/P1889'), ('propertyName', 'different from')]
# 8

# %%
#Return all distinct types of objects connected to the "Creative work node"
queryString = """
SELECT DISTINCT ?type ?typeName
WHERE {

    # ?creativeWork wdt:P31 wd:Q17537576.
    # ?creativeWork ?predicate ?object.
    # ?object wdt:P31 ?type.
    # ?type <http://schema.org/name> ?typeName.
}
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('type', 'http://www.wikidata.org/entity/Q1489259'), ('typeName', 'superpower')]
# [('type', 'http://www.wikidata.org/entity/Q559618'), ('typeName', 'fictional universe')]
# [('type', 'http://www.wikidata.org/entity/Q7810129'), ('typeName', 'title of authority')]
# [('type', 'http://www.wikidata.org/entity/Q16695773'), ('typeName', 'WikiProject')]
# [('type', 'http://www.wikidata.org/entity/Q20656220'), ('typeName', 'thriller genre')]
# [('type', 'http://www.wikidata.org/entity/Q41511'), ('typeName', 'universal language')]
# [('type', 'http://www.wikidata.org/entity/Q1328899'), ('typeName', 'standards organization')]
# [('type', 'http://www.wikidata.org/entity/Q30301495'), ('typeName', 'legendary bird')]
# [('type', 'http://www.wikidata.org/entity/Q95074'), ('typeName', 'fictional character')]
# [('type', 'http://www.wikidata.org/entity/Q1320047'), ('typeName', 'book publisher')]
# [('type', 'http://www.wikidata.org/entity/Q1668024'), ('typeName', 'service on internet')]
# [('type', 'http://www.wikidata.org/entity/Q2085381'), ('typeName', 'publisher')]
# [('type', 'http://www.wikidata.org/entity/Q107487333'), ('typeName', 'type of musical work/composition')]
# [('type', 'http://www.wikidata.org/entity/Q108329096'), ('typeName', 'genre by art form')]
# [('type', 'http://www.wikidata.org/entity/Q12909644'), ('typeName', 'political ideology')]
# [('type', 'http://www.wikidata.org/entity/Q1792379'), ('typeName', 'art genre')]
# [('type', 'http://www.wikidata.org/entity/Q22811234'), ('typeName', 'branch of philosophy')]
# [('type', 'http://www.wikidata.org/entity/Q29048322'), ('typeName', 'vehicle model')]
# [('type', 'http://www.wikidata.org/entity/Q4349921'), ('typeName', 'first human')]
# [('type', 'http://www.wikidata.org/entity/Q56019'), ('typeName', 'military rank')]
# [('type', 'http://www.wikidata.org/entity/Q6949213'), ('typeName', 'mythological king')]
# [('type', 'http://www.wikidata.org/entity/Q16895642'), ('typeName', 'philosophical school')]
# [('type', 'http://www.wikidata.org/entity/Q1792644'), ('typeName', 'art style')]
# [('type', 'http://www.wikidata.org/entity/Q28171280'), ('typeName', 'ancient civilization')]
# [('type', 'http://www.wikidata.org/entity/Q3152824'), ('typeName', 'cultural institution')]
# [('type', 'http://www.wikidata.org/entity/Q483394'), ('typeName', 'genre')]
# [('type', 'http://www.wikidata.org/entity/Q708676'), ('typeName', 'charitable organization')]
# [('type', 'http://www.wikidata.org/entity/Q862597'), ('typeName', 'musical form')]
# [('type', 'http://www.wikidata.org/entity/Q879146'), ('typeName', 'Christian denomination')]
# [('type', 'http://www.wikidata.org/entity/Q99541706'), ('typeName', 'historical unrecognized state')]
# [('type', 'http://www.wikidata.org/entity/Q1824109'), ('typeName', 'song form')]
# [('type', 'http://www.wikidata.org/entity/Q213924'), ('typeName', 'codex')]
# [('type', 'http://www.wikidata.org/entity/Q56055944'), ('typeName', 'art form')]
# [('type', 'http://www.wikidata.org/entity/Q732577'), ('typeName', 'publication')]
# [('type', 'http://www.wikidata.org/entity/Q185363'), ('typeName', 'chronicle')]
# [('type', 'http://www.wikidata.org/entity/Q207170'), ('typeName', 'office suite')]
# [('type', 'http://www.wikidata.org/entity/Q384515'), ('typeName', 'treatise')]
# [('type', 'http://www.wikidata.org/entity/Q483639'), ('typeName', 'cloud computing')]
# [('type', 'http://www.wikidata.org/entity/Q659563'), ('typeName', 'video game genre')]
# [('type', 'http://www.wikidata.org/entity/Q16326794'), ('typeName', 'mythological serpent')]
# [('type', 'http://www.wikidata.org/entity/Q108317211'), ('typeName', 'novel genre')]
# [('type', 'http://www.wikidata.org/entity/Q1329623'), ('typeName', 'cultural center')]
# [('type', 'http://www.wikidata.org/entity/Q28050585'), ('typeName', 'period')]
# [('type', 'http://www.wikidata.org/entity/Q641118'), ('typeName', 'personality')]
# [('type', 'http://www.wikidata.org/entity/Q856234'), ('typeName', 'academic library')]
# [('type', 'http://www.wikidata.org/entity/Q108037652'), ('typeName', 'audio release format')]
# [('type', 'http://www.wikidata.org/entity/Q53731850'), ('typeName', 'individual copy of a book')]
# [('type', 'http://www.wikidata.org/entity/Q105543609'), ('typeName', 'musical work/composition')]
# [('type', 'http://www.wikidata.org/entity/Q10929058'), ('typeName', 'model')]
# [('type', 'http://www.wikidata.org/entity/Q1093829'), ('typeName', 'city of the United States')]
# [('type', 'http://www.wikidata.org/entity/Q11042'), ('typeName', 'culture')]
# [('type', 'http://www.wikidata.org/entity/Q112099'), ('typeName', 'island nation')]
# [('type', 'http://www.wikidata.org/entity/Q11266439'), ('typeName', 'Wikimedia template')]
# [('type', 'http://www.wikidata.org/entity/Q11424'), ('typeName', 'film')]
# [('type', 'http://www.wikidata.org/entity/Q11753321'), ('typeName', 'Wikimedia navigational template')]
# [('type', 'http://www.wikidata.org/entity/Q11862829'), ('typeName', 'academic discipline')]
# [('type', 'http://www.wikidata.org/entity/Q1221156'), ('typeName', 'state of Germany')]
# [('type', 'http://www.wikidata.org/entity/Q1288568'), ('typeName', 'modern language')]
# [('type', 'http://www.wikidata.org/entity/Q1292119'), ('typeName', 'style')]
# [('type', 'http://www.wikidata.org/entity/Q1307214'), ('typeName', 'form of government')]
# [('type', 'http://www.wikidata.org/entity/Q13405593'), ('typeName', 'nature deity')]
# [('type', 'http://www.wikidata.org/entity/Q13406463'), ('typeName', 'Wikimedia list article')]
# [('type', 'http://www.wikidata.org/entity/Q13414953'), ('typeName', 'religious denomination')]
# [('type', 'http://www.wikidata.org/entity/Q13442814'), ('typeName', 'scholarly article')]
# [('type', 'http://www.wikidata.org/entity/Q14406742'), ('typeName', 'comic book series')]
# [('type', 'http://www.wikidata.org/entity/Q1520223'), ('typeName', 'constitutional republic')]
# [('type', 'http://www.wikidata.org/entity/Q1549591'), ('typeName', 'big city')]
# [('type', 'http://www.wikidata.org/entity/Q15632617'), ('typeName', 'fictional human')]
# [('type', 'http://www.wikidata.org/entity/Q163740'), ('typeName', 'nonprofit organization')]
# [('type', 'http://www.wikidata.org/entity/Q1637706'), ('typeName', 'million city')]
# [('type', 'http://www.wikidata.org/entity/Q17524420'), ('typeName', 'aspect of history')]
# [('type', 'http://www.wikidata.org/entity/Q17537576'), ('typeName', 'creative work')]
# [('type', 'http://www.wikidata.org/entity/Q179805'), ('typeName', 'political philosophy')]
# [('type', 'http://www.wikidata.org/entity/Q183039'), ('typeName', 'form of state')]
# [('type', 'http://www.wikidata.org/entity/Q183342'), ('typeName', 'federal city of Russia')]
# [('type', 'http://www.wikidata.org/entity/Q188451'), ('typeName', 'music genre')]
# [('type', 'http://www.wikidata.org/entity/Q20181813'), ('typeName', 'colonial power')]
# [('type', 'http://www.wikidata.org/entity/Q207694'), ('typeName', 'art museum')]
# [('type', 'http://www.wikidata.org/entity/Q215380'), ('typeName', 'musical group')]
# [('type', 'http://www.wikidata.org/entity/Q2264924'), ('typeName', 'port settlement')]
# [('type', 'http://www.wikidata.org/entity/Q23442'), ('typeName', 'island')]
# [('type', 'http://www.wikidata.org/entity/Q235557'), ('typeName', 'file format')]
# [('type', 'http://www.wikidata.org/entity/Q2465832'), ('typeName', 'branch of science')]
# [('type', 'http://www.wikidata.org/entity/Q2661442'), ('typeName', 'W3C Recommendation')]
# [('type', 'http://www.wikidata.org/entity/Q2668072'), ('typeName', 'collection')]
# [('type', 'http://www.wikidata.org/entity/Q277759'), ('typeName', 'book series')]
# [('type', 'http://www.wikidata.org/entity/Q28640'), ('typeName', 'profession')]
# [('type', 'http://www.wikidata.org/entity/Q3024240'), ('typeName', 'historical country')]
# [('type', 'http://www.wikidata.org/entity/Q3026037'), ('typeName', 'Platonic dialogue')]
# [('type', 'http://www.wikidata.org/entity/Q33384'), ('typeName', 'dialect')]
# [('type', 'http://www.wikidata.org/entity/Q336'), ('typeName', 'science')]
# [('type', 'http://www.wikidata.org/entity/Q33742'), ('typeName', 'natural language')]
# [('type', 'http://www.wikidata.org/entity/Q34770'), ('typeName', 'language')]
# [('type', 'http://www.wikidata.org/entity/Q3502482'), ('typeName', 'cultural region')]
# [('type', 'http://www.wikidata.org/entity/Q3624078'), ('typeName', 'sovereign state')]
# [('type', 'http://www.wikidata.org/entity/Q37045'), ('typeName', 'markup language')]
# [('type', 'http://www.wikidata.org/entity/Q378427'), ('typeName', 'literary award')]
# [('type', 'http://www.wikidata.org/entity/Q386724'), ('typeName', 'work')]
# [('type', 'http://www.wikidata.org/entity/Q4167410'), ('typeName', 'Wikimedia disambiguation page')]
# [('type', 'http://www.wikidata.org/entity/Q4167836'), ('typeName', 'Wikimedia category')]
# [('type', 'http://www.wikidata.org/entity/Q4209223'), ('typeName', 'Rechtsstaat')]
# [('type', 'http://www.wikidata.org/entity/Q4263830'), ('typeName', 'literary form')]
# [('type', 'http://www.wikidata.org/entity/Q42744322'), ('typeName', 'urban municipality of Germany')]
# [('type', 'http://www.wikidata.org/entity/Q43229'), ('typeName', 'organization')]
# [('type', 'http://www.wikidata.org/entity/Q45400320'), ('typeName', 'open-access publisher')]
# [('type', 'http://www.wikidata.org/entity/Q4671286'), ('typeName', 'academic major')]
# [('type', 'http://www.wikidata.org/entity/Q47461344'), ('typeName', 'written work')]
# [('type', 'http://www.wikidata.org/entity/Q482994'), ('typeName', 'album')]
# [('type', 'http://www.wikidata.org/entity/Q4830453'), ('typeName', 'business')]
# [('type', 'http://www.wikidata.org/entity/Q48349'), ('typeName', 'empire')]
# [('type', 'http://www.wikidata.org/entity/Q484170'), ('typeName', 'commune of France')]
# [('type', 'http://www.wikidata.org/entity/Q5'), ('typeName', 'human')]
# [('type', 'http://www.wikidata.org/entity/Q506240'), ('typeName', 'television film')]
# [('type', 'http://www.wikidata.org/entity/Q5119'), ('typeName', 'capital')]
# [('type', 'http://www.wikidata.org/entity/Q512187'), ('typeName', 'federal republic')]
# [('type', 'http://www.wikidata.org/entity/Q51576574'), ('typeName', 'Mediterranean country')]
# [('type', 'http://www.wikidata.org/entity/Q5255892'), ('typeName', 'democratic republic')]
# [('type', 'http://www.wikidata.org/entity/Q5292'), ('typeName', 'encyclopedia')]
# [('type', 'http://www.wikidata.org/entity/Q5372'), ('typeName', 'basketball')]
# [('type', 'http://www.wikidata.org/entity/Q5398426'), ('typeName', 'television series')]
# [('type', 'http://www.wikidata.org/entity/Q570116'), ('typeName', 'tourist attraction')]
# [('type', 'http://www.wikidata.org/entity/Q593744'), ('typeName', 'knowledge base')]
# [('type', 'http://www.wikidata.org/entity/Q615699'), ('typeName', 'Internet encyclopedia')]
# [('type', 'http://www.wikidata.org/entity/Q62049'), ('typeName', 'county seat')]
# [('type', 'http://www.wikidata.org/entity/Q6256'), ('typeName', 'country')]
# [('type', 'http://www.wikidata.org/entity/Q627436'), ('typeName', 'field of work')]
# [('type', 'http://www.wikidata.org/entity/Q707813'), ('typeName', 'Hanseatic city')]
# [('type', 'http://www.wikidata.org/entity/Q7094076'), ('typeName', 'online database')]
# [('type', 'http://www.wikidata.org/entity/Q7270'), ('typeName', 'republic')]
# [('type', 'http://www.wikidata.org/entity/Q7725634'), ('typeName', 'literary work')]
# [('type', 'http://www.wikidata.org/entity/Q7930989'), ('typeName', 'city/town')]
# [('type', 'http://www.wikidata.org/entity/Q8187769'), ('typeName', 'economic activity')]
# [('type', 'http://www.wikidata.org/entity/Q82794'), ('typeName', 'geographic region')]
# [('type', 'http://www.wikidata.org/entity/Q839954'), ('typeName', 'archaeological site')]
# [('type', 'http://www.wikidata.org/entity/Q859563'), ('typeName', 'secular state')]
# [('type', 'http://www.wikidata.org/entity/Q891723'), ('typeName', 'public company')]
# [('type', 'http://www.wikidata.org/entity/Q9212979'), ('typeName', 'musical duo')]
# [('type', 'http://www.wikidata.org/entity/Q11177771'), ('typeName', 'artistic technique')]
# [('type', 'http://www.wikidata.org/entity/Q11288'), ('typeName', 'web server')]
# [('type', 'http://www.wikidata.org/entity/Q218616'), ('typeName', 'proprietary software')]
# [('type', 'http://www.wikidata.org/entity/Q8148'), ('typeName', 'industry')]
# [('type', 'http://www.wikidata.org/entity/Q14204246'), ('typeName', 'Wikimedia project page')]
# [('type', 'http://www.wikidata.org/entity/Q152559'), ('typeName', 'macrolanguage')]
# [('type', 'http://www.wikidata.org/entity/Q1620908'), ('typeName', 'historical region')]
# [('type', 'http://www.wikidata.org/entity/Q18127'), ('typeName', 'record label')]
# [('type', 'http://www.wikidata.org/entity/Q182545'), ('typeName', 'stylistic device')]
# [('type', 'http://www.wikidata.org/entity/Q196294'), ('typeName', 'free license')]
# [('type', 'http://www.wikidata.org/entity/Q223393'), ('typeName', 'literary genre')]
# [('type', 'http://www.wikidata.org/entity/Q226730'), ('typeName', 'silent film')]
# [('type', 'http://www.wikidata.org/entity/Q22988604'), ('typeName', 'mythological Greek character')]
# [('type', 'http://www.wikidata.org/entity/Q24017414'), ('typeName', 'second-order class')]
# [('type', 'http://www.wikidata.org/entity/Q3238057'), ('typeName', 'proprietary license')]
# [('type', 'http://www.wikidata.org/entity/Q32880'), ('typeName', 'architectural style')]
# [('type', 'http://www.wikidata.org/entity/Q3320743'), ('typeName', 'title of honor')]
# [('type', 'http://www.wikidata.org/entity/Q3331189'), ('typeName', 'version, edition, or translation')]
# [('type', 'http://www.wikidata.org/entity/Q33506'), ('typeName', 'museum')]
# [('type', 'http://www.wikidata.org/entity/Q39816'), ('typeName', 'valley')]
# [('type', 'http://www.wikidata.org/entity/Q41176'), ('typeName', 'building')]
# [('type', 'http://www.wikidata.org/entity/Q417175'), ('typeName', 'kingdom')]
# [('type', 'http://www.wikidata.org/entity/Q49084'), ('typeName', 'short story')]
# [('type', 'http://www.wikidata.org/entity/Q50330360'), ('typeName', 'second largest city')]
# [('type', 'http://www.wikidata.org/entity/Q50424085'), ('typeName', 'copyright status')]
# [('type', 'http://www.wikidata.org/entity/Q60484681'), ('typeName', 'computer model series')]
# [('type', 'http://www.wikidata.org/entity/Q7075'), ('typeName', 'library')]
# [('type', 'http://www.wikidata.org/entity/Q7889'), ('typeName', 'video game')]
# [('type', 'http://www.wikidata.org/entity/Q968159'), ('typeName', 'art movement')]
# [('type', 'http://www.wikidata.org/entity/Q1400264'), ('typeName', 'artist collective')]
# [('type', 'http://www.wikidata.org/entity/Q1469824'), ('typeName', 'controlled vocabulary')]
# [('type', 'http://www.wikidata.org/entity/Q24451526'), ('typeName', 'data serialization format')]
# [('type', 'http://www.wikidata.org/entity/Q58795659'), ('typeName', 'major')]
# [('type', 'http://www.wikidata.org/entity/Q951873'), ('typeName', 'ethnolect')]
# [('type', 'http://www.wikidata.org/entity/Q1609504'), ('typeName', 'regional bibliography')]
# [('type', 'http://www.wikidata.org/entity/Q19478619'), ('typeName', 'metaclass')]
# [('type', 'http://www.wikidata.org/entity/Q1525071'), ('typeName', 'universal encyclopedia')]
# [('type', 'http://www.wikidata.org/entity/Q101609'), ('typeName', 'Twelve Olympians')]
# [('type', 'http://www.wikidata.org/entity/Q13002315'), ('typeName', 'legendary figure')]
# [('type', 'http://www.wikidata.org/entity/Q13393265'), ('typeName', 'basketball team')]
# [('type', 'http://www.wikidata.org/entity/Q1387388'), ('typeName', 'mythical hybrid')]
# [('type', 'http://www.wikidata.org/entity/Q15727816'), ('typeName', 'painting series')]
# [('type', 'http://www.wikidata.org/entity/Q1667921'), ('typeName', 'novel series')]
# [('type', 'http://www.wikidata.org/entity/Q178885'), ('typeName', 'deity')]
# [('type', 'http://www.wikidata.org/entity/Q18325436'), ('typeName', '501(c)(3) organization')]
# [('type', 'http://www.wikidata.org/entity/Q21070568'), ('typeName', 'human who may be fictional')]
# [('type', 'http://www.wikidata.org/entity/Q2198855'), ('typeName', 'cultural movement')]
# [('type', 'http://www.wikidata.org/entity/Q22698'), ('typeName', 'park')]
# [('type', 'http://www.wikidata.org/entity/Q22989102'), ('typeName', 'Greek deity')]
# [('type', 'http://www.wikidata.org/entity/Q2315359'), ('typeName', 'historical language')]
# [('type', 'http://www.wikidata.org/entity/Q268592'), ('typeName', 'industry')]
# [('type', 'http://www.wikidata.org/entity/Q284742'), ('typeName', 'Creative Commons license')]
# [('type', 'http://www.wikidata.org/entity/Q32738'), ('typeName', 'microcomputer')]
# [('type', 'http://www.wikidata.org/entity/Q37484'), ('typeName', 'epic poem')]
# [('type', 'http://www.wikidata.org/entity/Q38058796'), ('typeName', 'extinct language')]
# [('type', 'http://www.wikidata.org/entity/Q4271324'), ('typeName', 'mythical character')]
# [('type', 'http://www.wikidata.org/entity/Q436240'), ('typeName', 'ancient language')]
# [('type', 'http://www.wikidata.org/entity/Q45762'), ('typeName', 'dead language')]
# [('type', 'http://www.wikidata.org/entity/Q48204'), ('typeName', 'voluntary organization')]
# [('type', 'http://www.wikidata.org/entity/Q48498'), ('typeName', 'illuminated manuscript')]
# [('type', 'http://www.wikidata.org/entity/Q5185279'), ('typeName', 'poem')]
# [('type', 'http://www.wikidata.org/entity/Q55990535'), ('typeName', 'computer model')]
# [('type', 'http://www.wikidata.org/entity/Q571'), ('typeName', 'book')]
# [('type', 'http://www.wikidata.org/entity/Q838948'), ('typeName', 'work of art')]
# [('type', 'http://www.wikidata.org/entity/Q839470'), ('typeName', 'sacred language')]
# [('type', 'http://www.wikidata.org/entity/Q9134'), ('typeName', 'mythology')]
# [('type', 'http://www.wikidata.org/entity/Q9135'), ('typeName', 'operating system')]
# [('type', 'http://www.wikidata.org/entity/Q925381'), ('typeName', 'city with powiat rights')]
# [('type', 'http://www.wikidata.org/entity/Q96116695'), ('typeName', 'type of system')]
# [('type', 'http://www.wikidata.org/entity/Q23847174'), ('typeName', 'religious concept')]
# [('type', 'http://www.wikidata.org/entity/Q735'), ('typeName', 'art')]
# [('type', 'http://www.wikidata.org/entity/Q13212489'), ('typeName', 'county of California')]
# [('type', 'http://www.wikidata.org/entity/Q18602566'), ('typeName', 'book format')]
# [('type', 'http://www.wikidata.org/entity/Q3326717'), ('typeName', 'literary movement')]
# [('type', 'http://www.wikidata.org/entity/Q1724915'), ('typeName', 'use')]
# [('type', 'http://www.wikidata.org/entity/Q17489659'), ('typeName', 'group of works')]
# [('type', 'http://www.wikidata.org/entity/Q19610271'), ('typeName', 'literary term')]
# [('type', 'http://www.wikidata.org/entity/Q26879769'), ('typeName', 'state in the Confederation of the Rhine')]
# [('type', 'http://www.wikidata.org/entity/Q518261'), ('typeName', 'cultural area')]
# [('type', 'http://www.wikidata.org/entity/Q104624828'), ('typeName', 'book form')]
# [('type', 'http://www.wikidata.org/entity/Q1231896'), ('typeName', 'painting technique')]
# [('type', 'http://www.wikidata.org/entity/Q128093'), ('typeName', 'e-book')]
# [('type', 'http://www.wikidata.org/entity/Q3300034'), ('typeName', 'painting material')]
# [('type', 'http://www.wikidata.org/entity/Q7777573'), ('typeName', 'theatrical genre')]
# [('type', 'http://www.wikidata.org/entity/Q87167'), ('typeName', 'manuscript')]
# [('type', 'http://www.wikidata.org/entity/Q167037'), ('typeName', 'corporation')]
# [('type', 'http://www.wikidata.org/entity/Q19361238'), ('typeName', 'Wikidata metaclass')]
# [('type', 'http://www.wikidata.org/entity/Q621993'), ('typeName', 'literary class')]
# [('type', 'http://www.wikidata.org/entity/Q192822'), ('typeName', 'tonality')]
# [('type', 'http://www.wikidata.org/entity/Q2217301'), ('typeName', 'serial')]
# [('type', 'http://www.wikidata.org/entity/Q336705'), ('typeName', 'document file format')]
# [('type', 'http://www.wikidata.org/entity/Q34651'), ('typeName', 'Christian Church')]
# [('type', 'http://www.wikidata.org/entity/Q58795728'), ('typeName', 'minor')]
# [('type', 'http://www.wikidata.org/entity/Q7246201'), ('typeName', 'private foundation')]
# [('type', 'http://www.wikidata.org/entity/Q813912'), ('typeName', 'condition')]
# [('type', 'http://www.wikidata.org/entity/Q39811647'), ('typeName', 'translated work')]
# [('type', 'http://www.wikidata.org/entity/Q7631958'), ('typeName', 'subregion')]
# [('type', 'http://www.wikidata.org/entity/Q11723795'), ('typeName', 'piece')]
# [('type', 'http://www.wikidata.org/entity/Q668349'), ('typeName', 'kylix')]
# [('type', 'http://www.wikidata.org/entity/Q17152639'), ('typeName', 'thesaurus')]
# [('type', 'http://www.wikidata.org/entity/Q11396960'), ('typeName', 'production company')]
# [('type', 'http://www.wikidata.org/entity/Q64222339'), ('typeName', 'art term')]
# [('type', 'http://www.wikidata.org/entity/Q212971'), ('typeName', 'Request for Comments')]
# [('type', 'http://www.wikidata.org/entity/Q479716'), ('typeName', 'university press')]
# [('type', 'http://www.wikidata.org/entity/Q97772295'), ('typeName', 'skateboarding spot')]
# [('type', 'http://www.wikidata.org/entity/Q637866'), ('typeName', 'book review')]
# [('type', 'http://www.wikidata.org/entity/Q11771944'), ('typeName', 'civil service')]
# [('type', 'http://www.wikidata.org/entity/Q7257704'), ('typeName', 'public benefit organization')]
# [('type', 'http://www.wikidata.org/entity/Q975413'), ('typeName', 'encyclopedic dictionary')]
# [('type', 'http://www.wikidata.org/entity/Q1239328'), ('typeName', 'national encyclopedia')]
# [('type', 'http://www.wikidata.org/entity/Q5198626'), ('typeName', 'cycling club')]
# [('type', 'http://www.wikidata.org/entity/Q29918292'), ('typeName', 'cultural organization')]
# [('type', 'http://www.wikidata.org/entity/Q108368282'), ('typeName', 'genre by literary form')]
# [('type', 'http://www.wikidata.org/entity/Q92306274'), ('typeName', 'pseudo-author')]
# [('type', 'http://www.wikidata.org/entity/Q24296329'), ('typeName', 'mythological horse')]
# [('type', 'http://www.wikidata.org/entity/Q8432'), ('typeName', 'civilization')]
# [('type', 'http://www.wikidata.org/entity/Q17710986'), ('typeName', 'literary pentalogy')]
# [('type', 'http://www.wikidata.org/entity/Q193983'), ('typeName', 'metalanguage')]
# [('type', 'http://www.wikidata.org/entity/Q33123638'), ('typeName', 'Marxist theory')]
# [('type', 'http://www.wikidata.org/entity/Q1149626'), ('typeName', 'written language')]
# [('type', 'http://www.wikidata.org/entity/Q4942969'), ('typeName', 'Leishu')]
# [('type', 'http://www.wikidata.org/entity/Q30939938'), ('typeName', 'Open Definition conformant license')]
# [('type', 'http://www.wikidata.org/entity/Q15156455'), ('typeName', 'Wikisource language edition')]
# [('type', 'http://www.wikidata.org/entity/Q202686'), ('typeName', 'Commonwealth realm')]
# [('type', 'http://www.wikidata.org/entity/Q1641112'), ('typeName', 'social formation')]
# [('type', 'http://www.wikidata.org/entity/Q3048444'), ('typeName', 'school of economic thought')]
# [('type', 'http://www.wikidata.org/entity/Q672729'), ('typeName', 'Islamic republic')]
# [('type', 'http://www.wikidata.org/entity/Q1157107'), ('typeName', 'Daeva')]
# [('type', 'http://www.wikidata.org/entity/Q1386438'), ('typeName', 'state library of Germany')]
# [('type', 'http://www.wikidata.org/entity/Q55593943'), ('typeName', 'NISO standard')]
# [('type', 'http://www.wikidata.org/entity/Q22923920'), ('typeName', 'territorial collectivity of France with special status')]
# [('type', 'http://www.wikidata.org/entity/Q661936'), ('typeName', 'pro-drop language')]
# [('type', 'http://www.wikidata.org/entity/Q15831325'), ('typeName', 'class used in Universal Decimal Classification')]
# [('type', 'http://www.wikidata.org/entity/Q2065736'), ('typeName', 'cultural property')]
# [('type', 'http://www.wikidata.org/entity/Q737498'), ('typeName', 'academic journal')]
# [('type', 'http://www.wikidata.org/entity/Q1323642'), ('typeName', 'transcontinental country')]
# [('type', 'http://www.wikidata.org/entity/Q645883'), ('typeName', 'military operation')]
# [('type', 'http://www.wikidata.org/entity/Q6647660'), ('typeName', 'literary element')]
# [('type', 'http://www.wikidata.org/entity/Q15661340'), ('typeName', 'ancient city')]
# [('type', 'http://www.wikidata.org/entity/Q1901835'), ('typeName', 'seat of government')]
# [('type', 'http://www.wikidata.org/entity/Q200250'), ('typeName', 'metropolis')]
# [('type', 'http://www.wikidata.org/entity/Q24354'), ('typeName', 'theatre')]
# [('type', 'http://www.wikidata.org/entity/Q3685476'), ('typeName', 'abolished municipality in Italy')]
# [('type', 'http://www.wikidata.org/entity/Q515'), ('typeName', 'city')]
# [('type', 'http://www.wikidata.org/entity/Q902814'), ('typeName', 'border town')]
# [('type', 'http://www.wikidata.org/entity/Q2202509'), ('typeName', 'Roman city')]
# [('type', 'http://www.wikidata.org/entity/Q1063547'), ('typeName', 'voice type')]
# [('type', 'http://www.wikidata.org/entity/Q133156'), ('typeName', 'colony')]
# [('type', 'http://www.wikidata.org/entity/Q5633421'), ('typeName', 'scientific journal')]
# [('type', 'http://www.wikidata.org/entity/Q105756498'), ('typeName', 'type of musical ensemble/group')]
# [('type', 'http://www.wikidata.org/entity/Q877290'), ('typeName', 'Gemeindebau')]
# [('type', 'http://www.wikidata.org/entity/Q17544377'), ('typeName', 'history of a country or state')]
# [('type', 'http://www.wikidata.org/entity/Q1799072'), ('typeName', 'method')]
# [('type', 'http://www.wikidata.org/entity/Q34876'), ('typeName', 'province')]
# [('type', 'http://www.wikidata.org/entity/Q8192'), ('typeName', 'writing system')]
# [('type', 'http://www.wikidata.org/entity/Q29575627'), ('typeName', 'Latin-script alphabet')]
# [('type', 'http://www.wikidata.org/entity/Q60310061'), ('typeName', 'branch of theology')]
# [('type', 'http://www.wikidata.org/entity/Q24336068'), ('typeName', 'mythical war')]
# [('type', 'http://www.wikidata.org/entity/Q190995'), ('typeName', 'essence')]
# [('type', 'http://www.wikidata.org/entity/Q41710'), ('typeName', 'ethnic group')]
# [('type', 'http://www.wikidata.org/entity/Q42470'), ('typeName', 'motto')]
# [('type', 'http://www.wikidata.org/entity/Q12139612'), ('typeName', 'list')]
# [('type', 'http://www.wikidata.org/entity/Q41796'), ('typeName', 'sentence')]
# [('type', 'http://www.wikidata.org/entity/Q28598684'), ('typeName', 'branch of biology')]
# [('type', 'http://www.wikidata.org/entity/Q5107'), ('typeName', 'continent')]
# [('type', 'http://www.wikidata.org/entity/Q187931'), ('typeName', 'phrase')]
# [('type', 'http://www.wikidata.org/entity/Q1969448'), ('typeName', 'term')]
# [('type', 'http://www.wikidata.org/entity/Q855697'), ('typeName', 'subcontinent')]
# [('type', 'http://www.wikidata.org/entity/Q328376'), ('typeName', 'Nazi plunder')]
# [('type', 'http://www.wikidata.org/entity/Q80071'), ('typeName', 'symbol')]
# [('type', 'http://www.wikidata.org/entity/Q41397'), ('typeName', 'genocide')]
# [('type', 'http://www.wikidata.org/entity/Q33104279'), ('typeName', 'philosophical concept')]
# [('type', 'http://www.wikidata.org/entity/Q15709879'), ('typeName', 'artwork series')]
# [('type', 'http://www.wikidata.org/entity/Q21076217'), ('typeName', 'art project')]
# [('type', 'http://www.wikidata.org/entity/Q2135465'), ('typeName', 'legal concept')]
# [('type', 'http://www.wikidata.org/entity/Q187685'), ('typeName', 'doctoral thesis')]
# [('type', 'http://www.wikidata.org/entity/Q2393315'), ('typeName', 'dance festival')]
# [('type', 'http://www.wikidata.org/entity/Q58483088'), ('typeName', 'choreographic work')]
# [('type', 'http://www.wikidata.org/entity/Q11315'), ('typeName', 'shopping center')]
# [('type', 'http://www.wikidata.org/entity/Q1187811'), ('typeName', 'college town')]
# [('type', 'http://www.wikidata.org/entity/Q1190554'), ('typeName', 'occurrence')]
# [('type', 'http://www.wikidata.org/entity/Q123480'), ('typeName', 'landlocked country')]
# [('type', 'http://www.wikidata.org/entity/Q134626'), ('typeName', 'district capital')]
# [('type', 'http://www.wikidata.org/entity/Q13539802'), ('typeName', 'place with town rights and privileges')]
# [('type', 'http://www.wikidata.org/entity/Q16560'), ('typeName', 'palace')]
# [('type', 'http://www.wikidata.org/entity/Q22649'), ('typeName', 'antisemitism')]
# [('type', 'http://www.wikidata.org/entity/Q253030'), ('typeName', 'major regional center')]
# [('type', 'http://www.wikidata.org/entity/Q35127'), ('typeName', 'website')]
# [('type', 'http://www.wikidata.org/entity/Q42240'), ('typeName', 'research')]
# [('type', 'http://www.wikidata.org/entity/Q43702'), ('typeName', 'federation')]
# [('type', 'http://www.wikidata.org/entity/Q619610'), ('typeName', 'social state')]
# [('type', 'http://www.wikidata.org/entity/Q63791824'), ('typeName', 'country bordering the Baltic Sea')]
# [('type', 'http://www.wikidata.org/entity/Q676050'), ('typeName', 'old town')]
# [('type', 'http://www.wikidata.org/entity/Q702492'), ('typeName', 'urban area')]
# [('type', 'http://www.wikidata.org/entity/Q8434'), ('typeName', 'education')]
# [('type', 'http://www.wikidata.org/entity/Q856076'), ('typeName', 'municipality of Finland')]
# [('type', 'http://www.wikidata.org/entity/Q85631896'), ('typeName', 'urban district of Bavaria')]
# [('type', 'http://www.wikidata.org/entity/Q1497364'), ('typeName', 'building complex')]
# [('type', 'http://www.wikidata.org/entity/Q11303'), ('typeName', 'skyscraper')]
# [('type', 'http://www.wikidata.org/entity/Q15275719'), ('typeName', 'recurring event')]
# [('type', 'http://www.wikidata.org/entity/Q17431399'), ('typeName', 'national museum')]
# [('type', 'http://www.wikidata.org/entity/Q20155966'), ('typeName', 'XML application')]
# [('type', 'http://www.wikidata.org/entity/Q22806'), ('typeName', 'national library')]
# [('type', 'http://www.wikidata.org/entity/Q2352616'), ('typeName', 'catalogue')]
# [('type', 'http://www.wikidata.org/entity/Q27686'), ('typeName', 'hotel')]
# [('type', 'http://www.wikidata.org/entity/Q104782082'), ('typeName', 'territory outside RCM')]
# [('type', 'http://www.wikidata.org/entity/Q10617810'), ('typeName', 'punctuation mark')]
# [('type', 'http://www.wikidata.org/entity/Q27676416'), ('typeName', 'city or town')]
# [('type', 'http://www.wikidata.org/entity/Q4502142'), ('typeName', 'visual artwork')]
# [('type', 'http://www.wikidata.org/entity/Q667509'), ('typeName', 'municipality of Austria')]
# [('type', 'http://www.wikidata.org/entity/Q2727213'), ('typeName', 'theft')]
# [('type', 'http://www.wikidata.org/entity/Q2983893'), ('typeName', 'quarter')]
# [('type', 'http://www.wikidata.org/entity/Q7275'), ('typeName', 'state')]
# [('type', 'http://www.wikidata.org/entity/Q212805'), ('typeName', 'digital library')]
# [('type', 'http://www.wikidata.org/entity/Q12104174'), ('typeName', 'ethnographic museum')]
# [('type', 'http://www.wikidata.org/entity/Q88667167'), ('typeName', 'museum network')]
# [('type', 'http://www.wikidata.org/entity/Q49850'), ('typeName', 'journal')]
# [('type', 'http://www.wikidata.org/entity/Q1062404'), ('typeName', "artist's book")]
# [('type', 'http://www.wikidata.org/entity/Q55594385'), ('typeName', 'dictionary of a specific language')]
# [('type', 'http://www.wikidata.org/entity/Q779415'), ('typeName', 'special administrative region of China')]
# [('type', 'http://www.wikidata.org/entity/Q62500932'), ('typeName', 'digital humanities project')]
# [('type', 'http://www.wikidata.org/entity/Q44342'), ('typeName', 'legend')]
# [('type', 'http://www.wikidata.org/entity/Q1385450'), ('typeName', 'dissertation')]
# [('type', 'http://www.wikidata.org/entity/Q66458650'), ('typeName', 'sociological neighborhood')]
# [('type', 'http://www.wikidata.org/entity/Q180856'), ('typeName', 'choreography')]
# [('type', 'http://www.wikidata.org/entity/Q768717'), ('typeName', 'private collection')]
# [('type', 'http://www.wikidata.org/entity/Q1047437'), ('typeName', 'copyright collective')]
# [('type', 'http://www.wikidata.org/entity/Q13634374'), ('typeName', 'ethnic violence')]
# [('type', 'http://www.wikidata.org/entity/Q457843'), ('typeName', 'album amicorum')]
# [('type', 'http://www.wikidata.org/entity/Q66739237'), ('typeName', 'publishing term')]
# [('type', 'http://www.wikidata.org/entity/Q60198902'), ('typeName', 'hosting foundation')]
# [('type', 'http://www.wikidata.org/entity/Q742421'), ('typeName', 'theatrical troupe')]
# [('type', 'http://www.wikidata.org/entity/Q105420'), ('typeName', 'anthology')]
# [('type', 'http://www.wikidata.org/entity/Q28790362'), ('typeName', 'ethnic community')]
# [('type', 'http://www.wikidata.org/entity/Q17444909'), ('typeName', 'astronomical object type')]
# [('type', 'http://www.wikidata.org/entity/Q17737'), ('typeName', 'theory')]
# [('type', 'http://www.wikidata.org/entity/Q766875'), ('typeName', 'ethnic conflict')]
# [('type', 'http://www.wikidata.org/entity/Q36192'), ('typeName', 'folklore')]
# [('type', 'http://www.wikidata.org/entity/Q3774758'), ('typeName', 'sectarian violence')]
# [('type', 'http://www.wikidata.org/entity/Q25379'), ('typeName', 'play')]
# [('type', 'http://www.wikidata.org/entity/Q33104069'), ('typeName', 'political concept')]
# [('type', 'http://www.wikidata.org/entity/Q5707594'), ('typeName', 'news article')]
# [('type', 'http://www.wikidata.org/entity/Q18783400'), ('typeName', 'genre of sculpture')]
# [('type', 'http://www.wikidata.org/entity/Q11514315'), ('typeName', 'historical period')]
# [('type', 'http://www.wikidata.org/entity/Q14770218'), ('typeName', 'cantonal capital of Switzerland')]
# [('type', 'http://www.wikidata.org/entity/Q250811'), ('typeName', 'sub-province-level division')]
# [('type', 'http://www.wikidata.org/entity/Q35657'), ('typeName', 'U.S. state')]
# [('type', 'http://www.wikidata.org/entity/Q54935504'), ('typeName', 'city of Switzerland')]
# [('type', 'http://www.wikidata.org/entity/Q70208'), ('typeName', 'municipality of Switzerland')]
# [('type', 'http://www.wikidata.org/entity/Q747074'), ('typeName', 'comune of Italy')]
# [('type', 'http://www.wikidata.org/entity/Q748149'), ('typeName', 'prefecture-level city')]
# [('type', 'http://www.wikidata.org/entity/Q1047113'), ('typeName', 'specialty')]
# [('type', 'http://www.wikidata.org/entity/Q12102963'), ('typeName', 'city specifically designated in the state plan')]
# [('type', 'http://www.wikidata.org/entity/Q1914636'), ('typeName', 'activity')]
# [('type', 'http://www.wikidata.org/entity/Q2608849'), ('typeName', 'imprint')]
# [('type', 'http://www.wikidata.org/entity/Q33104303'), ('typeName', 'concept in physics')]
# [('type', 'http://www.wikidata.org/entity/Q21711025'), ('typeName', 'sculpture technique')]
# [('type', 'http://www.wikidata.org/entity/Q25295'), ('typeName', 'language family')]
# [('type', 'http://www.wikidata.org/entity/Q58483083'), ('typeName', 'dramatico-musical work')]
# [('type', 'http://www.wikidata.org/entity/Q89362829'), ('typeName', 'non-music')]
# [('type', 'http://www.wikidata.org/entity/Q33104129'), ('typeName', 'sociological concept')]
# [('type', 'http://www.wikidata.org/entity/Q1279564'), ('typeName', 'short story collection')]
# [('type', 'http://www.wikidata.org/entity/Q1555508'), ('typeName', 'radio program')]
# [('type', 'http://www.wikidata.org/entity/Q667276'), ('typeName', 'art exhibition')]
# [('type', 'http://www.wikidata.org/entity/Q955824'), ('typeName', 'learned society')]
# [('type', 'http://www.wikidata.org/entity/Q61708099'), ('typeName', 'urban district in Saxony')]
# [('type', 'http://www.wikidata.org/entity/Q108466143'), ('typeName', 'non-fiction genre')]
# [('type', 'http://www.wikidata.org/entity/Q51929311'), ('typeName', 'largest city')]
# [('type', 'http://www.wikidata.org/entity/Q96251598'), ('typeName', 'type of object')]
# [('type', 'http://www.wikidata.org/entity/Q785260'), ('typeName', 'phase of human life')]
# [('type', 'http://www.wikidata.org/entity/Q18551781'), ('typeName', 'subdistrict')]
# [('type', 'http://www.wikidata.org/entity/Q223557'), ('typeName', 'physical object')]
# [('type', 'http://www.wikidata.org/entity/Q186165'), ('typeName', 'web portal')]
# [('type', 'http://www.wikidata.org/entity/Q47913'), ('typeName', 'intelligence agency')]
# [('type', 'http://www.wikidata.org/entity/Q7315155'), ('typeName', 'research center')]
# [('type', 'http://www.wikidata.org/entity/Q1408286'), ('typeName', 'production process')]
# [('type', 'http://www.wikidata.org/entity/Q2270606'), ('typeName', 'spiritual practice')]
# [('type', 'http://www.wikidata.org/entity/Q15831577'), ('typeName', 'non-classical state of matter')]
# [('type', 'http://www.wikidata.org/entity/Q7328910'), ('typeName', 'art collection')]
# [('type', 'http://www.wikidata.org/entity/Q21114848'), ('typeName', 'magazine genre')]
# [('type', 'http://www.wikidata.org/entity/Q6055843'), ('typeName', 'internet genre')]
# [('type', 'http://www.wikidata.org/entity/Q24243801'), ('typeName', 'universal classification scheme')]
# [('type', 'http://www.wikidata.org/entity/Q11812394'), ('typeName', 'theatre company')]
# [('type', 'http://www.wikidata.org/entity/Q48264'), ('typeName', 'gender identity')]
# [('type', 'http://www.wikidata.org/entity/Q829080'), ('typeName', 'professional association')]
# [('type', 'http://www.wikidata.org/entity/Q108458'), ('typeName', 'meditation')]
# [('type', 'http://www.wikidata.org/entity/Q559856'), ('typeName', 'online video platform')]
# [('type', 'http://www.wikidata.org/entity/Q11344'), ('typeName', 'chemical element')]
# [('type', 'http://www.wikidata.org/entity/Q12737077'), ('typeName', 'occupation')]
# [('type', 'http://www.wikidata.org/entity/Q134556'), ('typeName', 'single')]
# [('type', 'http://www.wikidata.org/entity/Q165'), ('typeName', 'sea')]
# [('type', 'http://www.wikidata.org/entity/Q185836'), ('typeName', 'age of a person')]
# [('type', 'http://www.wikidata.org/entity/Q262166'), ('typeName', 'municipality of Germany')]
# [('type', 'http://www.wikidata.org/entity/Q3455524'), ('typeName', 'administrative region')]
# [('type', 'http://www.wikidata.org/entity/Q35456'), ('typeName', 'essential medicine')]
# [('type', 'http://www.wikidata.org/entity/Q6942562'), ('typeName', 'musical performance')]
# [('type', 'http://www.wikidata.org/entity/Q7366'), ('typeName', 'song')]
# [('type', 'http://www.wikidata.org/entity/Q214609'), ('typeName', 'material')]
# [('type', 'http://www.wikidata.org/entity/Q1589009'), ('typeName', 'privately held company')]
# [('type', 'http://www.wikidata.org/entity/Q2267705'), ('typeName', 'field of study')]
# [('type', 'http://www.wikidata.org/entity/Q41253'), ('typeName', 'movie theater')]
# [('type', 'http://www.wikidata.org/entity/Q1207369'), ('typeName', 'decimal classification')]
# [('type', 'http://www.wikidata.org/entity/Q815962'), ('typeName', 'colonization')]
# [('type', 'http://www.wikidata.org/entity/Q219067'), ('typeName', 'physical exercise')]
# [('type', 'http://www.wikidata.org/entity/Q21583365'), ('typeName', 'city')]
# [('type', 'http://www.wikidata.org/entity/Q223832'), ('typeName', 'dominion of the British Empire')]
# [('type', 'http://www.wikidata.org/entity/Q5852411'), ('typeName', 'state of Australia')]
# [('type', 'http://www.wikidata.org/entity/Q1936384'), ('typeName', 'area of mathematics')]
# [('type', 'http://www.wikidata.org/entity/Q4897819'), ('typeName', 'role')]
# [('type', 'http://www.wikidata.org/entity/Q107478770'), ('typeName', 'document genre')]
# [('type', 'http://www.wikidata.org/entity/Q3220391'), ('typeName', 'social networking service')]
# [('type', 'http://www.wikidata.org/entity/Q4369513'), ('typeName', 'sex of humans')]
# [('type', 'http://www.wikidata.org/entity/Q5151404'), ('typeName', 'comedic genre')]
# [('type', 'http://www.wikidata.org/entity/Q45971958'), ('typeName', 'performing arts genre')]
# [('type', 'http://www.wikidata.org/entity/Q1391014'), ('typeName', 'faceted classification')]
# [('type', 'http://www.wikidata.org/entity/Q9430'), ('typeName', 'ocean')]
# [('type', 'http://www.wikidata.org/entity/Q11812395'), ('typeName', 'theatre performance')]
# [('type', 'http://www.wikidata.org/entity/Q97430452'), ('typeName', 'performing arts industry')]
# [('type', 'http://www.wikidata.org/entity/Q1110794'), ('typeName', 'daily newspaper')]
# [('type', 'http://www.wikidata.org/entity/Q11032'), ('typeName', 'newspaper')]
# [('type', 'http://www.wikidata.org/entity/Q41298'), ('typeName', 'magazine')]
# [('type', 'http://www.wikidata.org/entity/Q1336152'), ('typeName', 'princely state')]
# [('type', 'http://www.wikidata.org/entity/Q194428'), ('typeName', 'stage')]
# [('type', 'http://www.wikidata.org/entity/Q545779'), ('typeName', 'pejorative')]
# [('type', 'http://www.wikidata.org/entity/Q79719'), ('typeName', 'license')]
# [('type', 'http://www.wikidata.org/entity/Q1497649'), ('typeName', 'memory institution')]
# [('type', 'http://www.wikidata.org/entity/Q2721136'), ('typeName', 'image hosting service')]
# [('type', 'http://www.wikidata.org/entity/Q16103215'), ('typeName', 'boat type')]
# [('type', 'http://www.wikidata.org/entity/Q21010817'), ('typeName', 'city of Pennsylvania')]
# [('type', 'http://www.wikidata.org/entity/Q6630149'), ('typeName', 'narrative form')]
# [('type', 'http://www.wikidata.org/entity/Q16521'), ('typeName', 'taxon')]
# [('type', 'http://www.wikidata.org/entity/Q21507383'), ('typeName', 'provincial or territorial capital city in Canada')]
# [('type', 'http://www.wikidata.org/entity/Q41362222'), ('typeName', 'type of map')]
# [('type', 'http://www.wikidata.org/entity/Q578'), ('typeName', 'century')]
# [('type', 'http://www.wikidata.org/entity/Q6881511'), ('typeName', 'enterprise')]
# [('type', 'http://www.wikidata.org/entity/Q9174'), ('typeName', 'religion')]
# [('type', 'http://www.wikidata.org/entity/Q14762300'), ('typeName', 'single-tier municipality')]
# [('type', 'http://www.wikidata.org/entity/Q17451'), ('typeName', 'typeface')]
# [('type', 'http://www.wikidata.org/entity/Q1826286'), ('typeName', 'religious movement')]
# [('type', 'http://www.wikidata.org/entity/Q181970'), ('typeName', 'archaism')]
# [('type', 'http://www.wikidata.org/entity/Q1221280'), ('typeName', 'folk tale')]
# [('type', 'http://www.wikidata.org/entity/Q620615'), ('typeName', 'mobile app')]
# [('type', 'http://www.wikidata.org/entity/Q21070598'), ('typeName', 'narrative entity')]
# [('type', 'http://www.wikidata.org/entity/Q3336843'), ('typeName', 'nation within the UK')]
# [('type', 'http://www.wikidata.org/entity/Q83365345'), ('typeName', 'vulnerable language')]
# [('type', 'http://www.wikidata.org/entity/Q1406161'), ('typeName', 'artistic theme')]
# [('type', 'http://www.wikidata.org/entity/Q22704077'), ('typeName', 'biblical episode')]
# [('type', 'http://www.wikidata.org/entity/Q119094'), ('typeName', 'human sacrifice')]
# [('type', 'http://www.wikidata.org/entity/Q12119802'), ('typeName', 'lyrical genre')]
# [('type', 'http://www.wikidata.org/entity/Q20202269'), ('typeName', 'musical term')]
# [('type', 'http://www.wikidata.org/entity/Q89522629'), ('typeName', 'poetic form')]
# [('type', 'http://www.wikidata.org/entity/Q1343246'), ('typeName', 'English country house')]
# [('type', 'http://www.wikidata.org/entity/Q646754'), ('typeName', 'open letter')]
# [('type', 'http://www.wikidata.org/entity/Q1209283'), ('typeName', 'electronic media')]
# [('type', 'http://www.wikidata.org/entity/Q4233718'), ('typeName', 'anonymous')]
# [('type', 'http://www.wikidata.org/entity/Q1752939'), ('typeName', 'independent agency of the United States government')]
# [('type', 'http://www.wikidata.org/entity/Q162827'), ('typeName', 'atlas')]
# [('type', 'http://www.wikidata.org/entity/Q2087181'), ('typeName', 'historic house museum')]
# [('type', 'http://www.wikidata.org/entity/Q11976924'), ('typeName', 'non medical phobia')]
# [('type', 'http://www.wikidata.org/entity/Q191776'), ('typeName', 'apologetics')]
# [('type', 'http://www.wikidata.org/entity/Q2074737'), ('typeName', 'municipality of Spain')]
# [('type', 'http://www.wikidata.org/entity/Q25106976'), ('typeName', 'cartographic work')]
# [('type', 'http://www.wikidata.org/entity/Q2695280'), ('typeName', 'technique')]
# [('type', 'http://www.wikidata.org/entity/Q3918'), ('typeName', 'university')]
# [('type', 'http://www.wikidata.org/entity/Q11060274'), ('typeName', 'print')]
# [('type', 'http://www.wikidata.org/entity/Q2122214'), ('typeName', 'national archives')]
# [('type', 'http://www.wikidata.org/entity/Q317557'), ('typeName', 'parish church')]
# [('type', 'http://www.wikidata.org/entity/Q327333'), ('typeName', 'government agency')]
# [('type', 'http://www.wikidata.org/entity/Q83365347'), ('typeName', 'definitely endangered language')]
# [('type', 'http://www.wikidata.org/entity/Q6107280'), ('typeName', 'revolt')]
# [('type', 'http://www.wikidata.org/entity/Q3588250'), ('typeName', 'ethnic riot')]
# [('type', 'http://www.wikidata.org/entity/Q120560'), ('typeName', 'minor basilica')]
# [('type', 'http://www.wikidata.org/entity/Q474090'), ('typeName', 'narrative poetry')]
# [('type', 'http://www.wikidata.org/entity/Q867335'), ('typeName', 'literary cycle')]
# [('type', 'http://www.wikidata.org/entity/Q97588309'), ('typeName', 'former cathedral')]
# [('type', 'http://www.wikidata.org/entity/Q7451247'), ('typeName', 'sentiment')]
# [('type', 'http://www.wikidata.org/entity/Q6957341'), ('typeName', 'major religious group')]
# [('type', 'http://www.wikidata.org/entity/Q7279589'), ('typeName', 'racial politics')]
# [('type', 'http://www.wikidata.org/entity/Q66724388'), ('typeName', 'autonomous country within the Kingdom of Denmark')]
# [('type', 'http://www.wikidata.org/entity/Q2358279'), ('typeName', 'commercium song')]
# [('type', 'http://www.wikidata.org/entity/Q59211454'), ('typeName', 'level of description')]
# [('type', 'http://www.wikidata.org/entity/Q257391'), ('typeName', 'federal capital')]
# [('type', 'http://www.wikidata.org/entity/Q717478'), ('typeName', 'administrative territorial entity of the United Kingdom')]
# [('type', 'http://www.wikidata.org/entity/Q157031'), ('typeName', 'foundation')]
# [('type', 'http://www.wikidata.org/entity/Q1066984'), ('typeName', 'financial centre')]
# [('type', 'http://www.wikidata.org/entity/Q133442'), ('typeName', 'city-state')]
# [('type', 'http://www.wikidata.org/entity/Q15974307'), ('typeName', 'Einheitsgemeinde of Germany')]
# [('type', 'http://www.wikidata.org/entity/Q22865'), ('typeName', 'independent city of Germany')]
# [('type', 'http://www.wikidata.org/entity/Q210223'), ('typeName', 'sloop')]
# [('type', 'http://www.wikidata.org/entity/Q618779'), ('typeName', 'award')]
# [('type', 'http://www.wikidata.org/entity/Q17888'), ('typeName', 'sexual orientation')]
# [('type', 'http://www.wikidata.org/entity/Q12857432'), ('typeName', 'Chinese dynasty')]
# [('type', 'http://www.wikidata.org/entity/Q31629'), ('typeName', 'type of sport')]
# [('type', 'http://www.wikidata.org/entity/Q3469910'), ('typeName', 'performing arts center')]
# [('type', 'http://www.wikidata.org/entity/Q4164871'), ('typeName', 'position')]
# [('type', 'http://www.wikidata.org/entity/Q50068795'), ('typeName', 'historical Chinese state')]
# [('type', 'http://www.wikidata.org/entity/Q11033'), ('typeName', 'mass media')]
# [('type', 'http://www.wikidata.org/entity/Q177634'), ('typeName', 'community')]
# [('type', 'http://www.wikidata.org/entity/Q21518270'), ('typeName', 'state or insular area capital in the United States')]
# [('type', 'http://www.wikidata.org/entity/Q55558200'), ('typeName', 'local government area of New South Wales')]
# [('type', 'http://www.wikidata.org/entity/Q20897549'), ('typeName', 'art institution')]
# [('type', 'http://www.wikidata.org/entity/Q4936952'), ('typeName', 'anatomical structure')]
# [('type', 'http://www.wikidata.org/entity/Q8205328'), ('typeName', 'artificial physical object')]
# [('type', 'http://www.wikidata.org/entity/Q11488158'), ('typeName', 'corporate title')]
# [('type', 'http://www.wikidata.org/entity/Q1665984'), ('typeName', 'interdisciplinary science')]
# [('type', 'http://www.wikidata.org/entity/Q836688'), ('typeName', 'ancient Chinese state')]
# [('type', 'http://www.wikidata.org/entity/Q127843'), ('typeName', 'pen name')]
# [('type', 'http://www.wikidata.org/entity/Q1066538'), ('typeName', 'National Central City')]
# [('type', 'http://www.wikidata.org/entity/Q217086'), ('typeName', 'story')]
# [('type', 'http://www.wikidata.org/entity/Q3535655'), ('typeName', 'cataloging')]
# [('type', 'http://www.wikidata.org/entity/Q4356073'), ('typeName', 'spectator sport')]
# [('type', 'http://www.wikidata.org/entity/Q4688879'), ('typeName', 'romantic orientation')]
# [('type', 'http://www.wikidata.org/entity/Q1208802'), ('typeName', 'direct-controlled municipality')]
# [('type', 'http://www.wikidata.org/entity/Q19984037'), ('typeName', 'weaving factory')]
# [('type', 'http://www.wikidata.org/entity/Q6501349'), ('typeName', 'parking lot')]
# [('type', 'http://www.wikidata.org/entity/Q151885'), ('typeName', 'concept')]
# [('type', 'http://www.wikidata.org/entity/Q482'), ('typeName', 'poetry')]
# [('type', 'http://www.wikidata.org/entity/Q11426'), ('typeName', 'metal')]
# [('type', 'http://www.wikidata.org/entity/Q79007'), ('typeName', 'street')]
# [('type', 'http://www.wikidata.org/entity/Q200539'), ('typeName', 'dress')]
# [('type', 'http://www.wikidata.org/entity/Q3184121'), ('typeName', 'municipality of Brazil')]
# [('type', 'http://www.wikidata.org/entity/Q194380'), ('typeName', 'Arabic literature')]
# [('type', 'http://www.wikidata.org/entity/Q1089515'), ('typeName', 'conquest dynasty')]
# [('type', 'http://www.wikidata.org/entity/Q3973051'), ('typeName', 'spinning mill')]
# [('type', 'http://www.wikidata.org/entity/Q76384697'), ('typeName', 'broadcloth factory')]
# [('type', 'http://www.wikidata.org/entity/Q14784328'), ('typeName', 'state capital in Germany')]
# [('type', 'http://www.wikidata.org/entity/Q15936437'), ('typeName', 'research university')]
# [('type', 'http://www.wikidata.org/entity/Q23002054'), ('typeName', 'private not-for-profit educational institution')]
# [('type', 'http://www.wikidata.org/entity/Q902104'), ('typeName', 'private university')]
# [('type', 'http://www.wikidata.org/entity/Q11483816'), ('typeName', 'annual event')]
# [('type', 'http://www.wikidata.org/entity/Q14073567'), ('typeName', 'sibling duo')]
# [('type', 'http://www.wikidata.org/entity/Q38033430'), ('typeName', 'class of award')]
# [('type', 'http://www.wikidata.org/entity/Q64348974'), ('typeName', 'LGBT event')]
# [('type', 'http://www.wikidata.org/entity/Q2915955'), ('typeName', 'philosophical movement')]
# [('type', 'http://www.wikidata.org/entity/Q203209'), ('typeName', 'conceptual art')]
# [('type', 'http://www.wikidata.org/entity/Q11633'), ('typeName', 'photography')]
# [('type', 'http://www.wikidata.org/entity/Q36649'), ('typeName', 'visual art')]
# [('type', 'http://www.wikidata.org/entity/Q2462003'), ('typeName', 'instant messaging client')]
# [('type', 'http://www.wikidata.org/entity/Q36774'), ('typeName', 'web page')]
# [('type', 'http://www.wikidata.org/entity/Q856584'), ('typeName', 'library building')]
# [('type', 'http://www.wikidata.org/entity/Q10648343'), ('typeName', 'duo')]
# [('type', 'http://www.wikidata.org/entity/Q170584'), ('typeName', 'project')]
# [('type', 'http://www.wikidata.org/entity/Q1110684'), ('typeName', 'professional regulatory body')]
# [('type', 'http://www.wikidata.org/entity/Q19953632'), ('typeName', 'former administrative territorial entity')]
# [('type', 'http://www.wikidata.org/entity/Q56256173'), ('typeName', 'class of chemical compounds with similar applications or functions')]
# [('type', 'http://www.wikidata.org/entity/Q399495'), ('typeName', 'standard language')]
# [('type', 'http://www.wikidata.org/entity/Q929651'), ('typeName', 'grassroots')]
# [('type', 'http://www.wikidata.org/entity/Q4536543'), ('typeName', 'pluricentric language variant')]
# [('type', 'http://www.wikidata.org/entity/Q49773'), ('typeName', 'social movement')]
# [('type', 'http://www.wikidata.org/entity/Q6266'), ('typeName', 'nation')]
# [('type', 'http://www.wikidata.org/entity/Q12089225'), ('typeName', 'mineral species')]
# [('type', 'http://www.wikidata.org/entity/Q13136'), ('typeName', 'reference work')]
# [('type', 'http://www.wikidata.org/entity/Q33430'), ('typeName', 'Kwa')]
# [('type', 'http://www.wikidata.org/entity/Q2604680'), ('typeName', 'target audience')]
# [('type', 'http://www.wikidata.org/entity/Q1097949'), ('typeName', 'literary language')]
# [('type', 'http://www.wikidata.org/entity/Q19958368'), ('typeName', 'culture of an area')]
# [('type', 'http://www.wikidata.org/entity/Q162633'), ('typeName', 'academy')]
# [('type', 'http://www.wikidata.org/entity/Q192161'), ('typeName', 'formal language')]
# [('type', 'http://www.wikidata.org/entity/Q57318'), ('typeName', 'free imperial city')]
# [('type', 'http://www.wikidata.org/entity/Q1547289'), ('typeName', 'Luther city')]
# [('type', 'http://www.wikidata.org/entity/Q576639'), ('typeName', 'essentially contested concept')]
# [('type', 'http://www.wikidata.org/entity/Q3275668'), ('typeName', 'national power')]
# [('type', 'http://www.wikidata.org/entity/Q2401485'), ('typeName', 'expedition')]
# [('type', 'http://www.wikidata.org/entity/Q2111762'), ('typeName', 'machine shop')]
# [('type', 'http://www.wikidata.org/entity/Q366301'), ('typeName', 'research expedition')]
# [('type', 'http://www.wikidata.org/entity/Q2516426'), ('typeName', 'transport ministry')]
# [('type', 'http://www.wikidata.org/entity/Q8436'), ('typeName', 'family')]
# [('type', 'http://www.wikidata.org/entity/Q8502'), ('typeName', 'mountain')]
# [('type', 'http://www.wikidata.org/entity/Q355472'), ('typeName', 'history of photography')]
# [('type', 'http://www.wikidata.org/entity/Q13417114'), ('typeName', 'noble family')]
# [('type', 'http://www.wikidata.org/entity/Q8072'), ('typeName', 'volcano')]
# [('type', 'http://www.wikidata.org/entity/Q910252'), ('typeName', 'United States federal executive department')]
# [('type', 'http://www.wikidata.org/entity/Q3337280'), ('typeName', 'marine navigation')]
# [('type', 'http://www.wikidata.org/entity/Q6622163'), ('typeName', 'heraldic authority')]
# [('type', 'http://www.wikidata.org/entity/Q8261'), ('typeName', 'novel')]
# [('type', 'http://www.wikidata.org/entity/Q34379'), ('typeName', 'musical instrument')]
# [('type', 'http://www.wikidata.org/entity/Q30149195'), ('typeName', 'biblical concept')]
# [('type', 'http://www.wikidata.org/entity/Q651118'), ('typeName', 'hypostasis')]
# [('type', 'http://www.wikidata.org/entity/Q15416'), ('typeName', 'television program')]
# [('type', 'http://www.wikidata.org/entity/Q15265344'), ('typeName', 'broadcaster')]
# [('type', 'http://www.wikidata.org/entity/Q3100808'), ('typeName', 'photography genre')]
# [('type', 'http://www.wikidata.org/entity/Q83405'), ('typeName', 'factory')]
# [('type', 'http://www.wikidata.org/entity/Q59152282'), ('typeName', 'video streaming service')]
# [('type', 'http://www.wikidata.org/entity/Q81941037'), ('typeName', 'product distribution method')]
# [('type', 'http://www.wikidata.org/entity/Q5932254'), ('typeName', 'demographic profile')]
# [('type', 'http://www.wikidata.org/entity/Q18674739'), ('typeName', 'event venue')]
# [('type', 'http://www.wikidata.org/entity/Q32090'), ('typeName', 'lifestyle')]
# [('type', 'http://www.wikidata.org/entity/Q3249551'), ('typeName', 'process')]
# [('type', 'http://www.wikidata.org/entity/Q470775'), ('typeName', 'a posteriori language')]
# [('type', 'http://www.wikidata.org/entity/Q103495'), ('typeName', 'world war')]
# [('type', 'http://www.wikidata.org/entity/Q171263'), ('typeName', 'agglutinative language')]
# [('type', 'http://www.wikidata.org/entity/Q33215'), ('typeName', 'constructed language')]
# [('type', 'http://www.wikidata.org/entity/Q49447'), ('typeName', 'world view')]
# [('type', 'http://www.wikidata.org/entity/Q1790577'), ('typeName', 'planned language')]
# [('type', 'http://www.wikidata.org/entity/Q7278'), ('typeName', 'political party')]
# [('type', 'http://www.wikidata.org/entity/Q193430'), ('typeName', 'heterocyclic compound')]
# [('type', 'http://www.wikidata.org/entity/Q465299'), ('typeName', 'archaeological culture')]
# [('type', 'http://www.wikidata.org/entity/Q838296'), ('typeName', 'international auxiliary language')]
# 635

# %%
#Return all properties that relates Paul Auster to an entity of type film
queryString = """
SELECT DISTINCT ?film
WHERE {

    # ?film wdt:P31 wd:Q11424.
    wd:Q214642 ?property ?film.
    # ?property <http://schema.org/name> ?propertyName.
}
"""

print("Results")
run_query(queryString)
# Out:
# Results
# Empty
# 0

# %%
#Return all properties that relates Ian to an entity of type film
queryString = """
SELECT DISTINCT ?property ?propertyName
WHERE {

    # ?film wdt:P31 wd:Q11424.
    wd:Q190379 ?property ?film.
    # ?property <http://schema.org/name> ?propertyName.
}
"""

print("Results")
run_query(queryString)
# Out:
# Results
# Empty
# 0

# %%
#Return all properties that relates a film object
queryString = """
SELECT DISTINCT ?property ?propertyName
WHERE {

    # ?film wdt:P31 wd:Q11424.
    # ?film ?property ?obj.
    # ?property <http://schema.org/name> ?propertyName.
}
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('property', 'http://www.wikidata.org/prop/direct/P2883'), ('propertyName', 'HKMDB film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7777'), ('propertyName', 'AdoroCinema film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1809'), ('propertyName', 'choreographer')]
# [('property', 'http://www.wikidata.org/prop/direct/P7519'), ('propertyName', 'Filmový přehled film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4606'), ('propertyName', 'National Film Board of Canada film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1040'), ('propertyName', 'film editor')]
# [('property', 'http://www.wikidata.org/prop/direct/P1113'), ('propertyName', 'number of episodes')]
# [('property', 'http://www.wikidata.org/prop/direct/P1237'), ('propertyName', 'Box Office Mojo film ID (former scheme)')]
# [('property', 'http://www.wikidata.org/prop/direct/P1258'), ('propertyName', 'Rotten Tomatoes ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1265'), ('propertyName', 'AlloCiné film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P136'), ('propertyName', 'genre')]
# [('property', 'http://www.wikidata.org/prop/direct/P1417'), ('propertyName', 'Encyclopædia Britannica Online ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1434'), ('propertyName', 'takes place in fictional universe')]
# [('property', 'http://www.wikidata.org/prop/direct/P144'), ('propertyName', 'based on')]
# [('property', 'http://www.wikidata.org/prop/direct/P1476'), ('propertyName', 'title')]
# [('property', 'http://www.wikidata.org/prop/direct/P154'), ('propertyName', 'logo image')]
# [('property', 'http://www.wikidata.org/prop/direct/P155'), ('propertyName', 'follows')]
# [('property', 'http://www.wikidata.org/prop/direct/P156'), ('propertyName', 'followed by')]
# [('property', 'http://www.wikidata.org/prop/direct/P1562'), ('propertyName', 'AllMovie title ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P161'), ('propertyName', 'cast member')]
# [('property', 'http://www.wikidata.org/prop/direct/P162'), ('propertyName', 'producer')]
# [('property', 'http://www.wikidata.org/prop/direct/P1657'), ('propertyName', 'MPAA film rating')]
# [('property', 'http://www.wikidata.org/prop/direct/P166'), ('propertyName', 'award received')]
# [('property', 'http://www.wikidata.org/prop/direct/P1712'), ('propertyName', 'Metacritic ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P175'), ('propertyName', 'performer')]
# [('property', 'http://www.wikidata.org/prop/direct/P179'), ('propertyName', 'part of the series')]
# [('property', 'http://www.wikidata.org/prop/direct/P18'), ('propertyName', 'image')]
# [('property', 'http://www.wikidata.org/prop/direct/P1804'), ('propertyName', 'DNF film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1874'), ('propertyName', 'Netflix ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1889'), ('propertyName', 'different from')]
# [('property', 'http://www.wikidata.org/prop/direct/P1970'), ('propertyName', 'MovieMeter film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1981'), ('propertyName', 'FSK film rating')]
# [('property', 'http://www.wikidata.org/prop/direct/P2002'), ('propertyName', 'Twitter username')]
# [('property', 'http://www.wikidata.org/prop/direct/P2013'), ('propertyName', 'Facebook ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2047'), ('propertyName', 'duration')]
# [('property', 'http://www.wikidata.org/prop/direct/P2061'), ('propertyName', 'aspect ratio')]
# [('property', 'http://www.wikidata.org/prop/direct/P2130'), ('propertyName', 'cost')]
# [('property', 'http://www.wikidata.org/prop/direct/P2142'), ('propertyName', 'box office')]
# [('property', 'http://www.wikidata.org/prop/direct/P2334'), ('propertyName', 'Swedish Film Database film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2346'), ('propertyName', 'Elonet movie ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2363'), ('propertyName', 'NMHH film rating')]
# [('property', 'http://www.wikidata.org/prop/direct/P2465'), ('propertyName', 'Allcinema film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2508'), ('propertyName', 'KINENOTE film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2509'), ('propertyName', 'Movie Walker film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2515'), ('propertyName', 'costume designer')]
# [('property', 'http://www.wikidata.org/prop/direct/P2518'), ('propertyName', 'Scope.dk film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2529'), ('propertyName', 'ČSFD film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2603'), ('propertyName', 'Kinopoisk film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2629'), ('propertyName', 'BBFC rating')]
# [('property', 'http://www.wikidata.org/prop/direct/P2631'), ('propertyName', 'TCM Movie Database film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2636'), ('propertyName', 'Minkultury film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2638'), ('propertyName', 'TV.com ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2639'), ('propertyName', 'Filmportal ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2671'), ('propertyName', 'Google Knowledge Graph ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2703'), ('propertyName', 'BFI National Archive work ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2704'), ('propertyName', 'EIDR content ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P272'), ('propertyName', 'production company')]
# [('property', 'http://www.wikidata.org/prop/direct/P2755'), ('propertyName', 'exploitation visa number')]
# [('property', 'http://www.wikidata.org/prop/direct/P2758'), ('propertyName', 'CNC film rating (France)')]
# [('property', 'http://www.wikidata.org/prop/direct/P3077'), ('propertyName', 'Cineplex Germany film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P31'), ('propertyName', 'instance of')]
# [('property', 'http://www.wikidata.org/prop/direct/P3107'), ('propertyName', 'LdiF ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3129'), ('propertyName', 'cine.gr film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3135'), ('propertyName', 'elCinema film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3138'), ('propertyName', 'OFDb film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3141'), ('propertyName', 'EDb film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3143'), ('propertyName', 'elFilm film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3145'), ('propertyName', 'Sratim ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3203'), ('propertyName', 'Ciné-Ressources film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3212'), ('propertyName', 'ISAN')]
# [('property', 'http://www.wikidata.org/prop/direct/P3302'), ('propertyName', 'Open Media Database film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3306'), ('propertyName', 'ICAA rating')]
# [('property', 'http://www.wikidata.org/prop/direct/P3340'), ('propertyName', 'Kvikmyndir film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3402'), ('propertyName', 'CNC film rating (Romania)')]
# [('property', 'http://www.wikidata.org/prop/direct/P3417'), ('propertyName', 'Quora topic ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P344'), ('propertyName', 'director of photography')]
# [('property', 'http://www.wikidata.org/prop/direct/P345'), ('propertyName', 'IMDb ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3593'), ('propertyName', 'AFI Catalog of Feature Films ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P364'), ('propertyName', 'original language of film or TV show')]
# [('property', 'http://www.wikidata.org/prop/direct/P3650'), ('propertyName', 'JMK film rating')]
# [('property', 'http://www.wikidata.org/prop/direct/P373'), ('propertyName', 'Commons category')]
# [('property', 'http://www.wikidata.org/prop/direct/P3804'), ('propertyName', 'TV Guide show ID (former scheme)')]
# [('property', 'http://www.wikidata.org/prop/direct/P3808'), ('propertyName', 'The Numbers movie ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3834'), ('propertyName', 'RTC film rating')]
# [('property', 'http://www.wikidata.org/prop/direct/P3844'), ('propertyName', 'Deutsche Synchronkartei film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3933'), ('propertyName', 'Cinema.de ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4276'), ('propertyName', 'Cinémathèque québécoise work identifier')]
# [('property', 'http://www.wikidata.org/prop/direct/P4282'), ('propertyName', 'LUMIERE film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P436'), ('propertyName', 'MusicBrainz release group ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P437'), ('propertyName', 'distribution format')]
# [('property', 'http://www.wikidata.org/prop/direct/P443'), ('propertyName', 'pronunciation audio')]
# [('property', 'http://www.wikidata.org/prop/direct/P4438'), ('propertyName', 'BFI Films, TV and people ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4529'), ('propertyName', 'Douban film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P462'), ('propertyName', 'color')]
# [('property', 'http://www.wikidata.org/prop/direct/P4632'), ('propertyName', 'Bechdel Test Movie List ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4665'), ('propertyName', 'CineMagia title ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4780'), ('propertyName', 'MYmovies movie ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4783'), ('propertyName', 'Movieplayer film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P480'), ('propertyName', 'FilmAffinity ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4947'), ('propertyName', 'TMDb movie ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P495'), ('propertyName', 'country of origin')]
# [('property', 'http://www.wikidata.org/prop/direct/P5021'), ('propertyName', 'assessment')]
# [('property', 'http://www.wikidata.org/prop/direct/P5032'), ('propertyName', 'Filmweb.pl film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5099'), ('propertyName', 'Il mondo dei doppiatori ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5128'), ('propertyName', 'ICAA film catalogue ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5680'), ('propertyName', 'Hoopla title ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P57'), ('propertyName', 'director')]
# [('property', 'http://www.wikidata.org/prop/direct/P577'), ('propertyName', 'publication date')]
# [('property', 'http://www.wikidata.org/prop/direct/P5786'), ('propertyName', 'Moviepilot.de film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P58'), ('propertyName', 'screenwriter')]
# [('property', 'http://www.wikidata.org/prop/direct/P5905'), ('propertyName', 'Comic Vine ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5970'), ('propertyName', 'Medierådet rating')]
# [('property', 'http://www.wikidata.org/prop/direct/P5987'), ('propertyName', 'Indiancine.ma film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6127'), ('propertyName', 'Letterboxd film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6216'), ('propertyName', 'copyright status')]
# [('property', 'http://www.wikidata.org/prop/direct/P6398'), ('propertyName', 'iTunes movie ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P646'), ('propertyName', 'Freebase ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6562'), ('propertyName', 'Google Play Movies & TV ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6584'), ('propertyName', 'Scripts.com script ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P676'), ('propertyName', 'lyrics by')]
# [('property', 'http://www.wikidata.org/prop/direct/P750'), ('propertyName', 'distributed by')]
# [('property', 'http://www.wikidata.org/prop/direct/P793'), ('propertyName', 'significant event')]
# [('property', 'http://www.wikidata.org/prop/direct/P7970'), ('propertyName', 'FandangoNow ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P8033'), ('propertyName', 'Movie Review Query Engine ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P8296'), ('propertyName', 'Cinema Context ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P840'), ('propertyName', 'narrative location')]
# [('property', 'http://www.wikidata.org/prop/direct/P8411'), ('propertyName', 'set in environment')]
# [('property', 'http://www.wikidata.org/prop/direct/P856'), ('propertyName', 'official website')]
# [('property', 'http://www.wikidata.org/prop/direct/P86'), ('propertyName', 'composer')]
# [('property', 'http://www.wikidata.org/prop/direct/P8687'), ('propertyName', 'social media followers')]
# [('property', 'http://www.wikidata.org/prop/direct/P905'), ('propertyName', 'PORT film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P910'), ('propertyName', "topic's main category")]
# [('property', 'http://www.wikidata.org/prop/direct/P915'), ('propertyName', 'filming location')]
# [('property', 'http://www.wikidata.org/prop/direct/P921'), ('propertyName', 'main subject')]
# [('property', 'http://www.wikidata.org/prop/direct/P9586'), ('propertyName', 'Apple TV movie ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2554'), ('propertyName', 'production designer')]
# [('property', 'http://www.wikidata.org/prop/direct/P1431'), ('propertyName', 'executive producer')]
# [('property', 'http://www.wikidata.org/prop/direct/P1877'), ('propertyName', 'after a work by')]
# [('property', 'http://www.wikidata.org/prop/direct/P2408'), ('propertyName', 'set in period')]
# [('property', 'http://www.wikidata.org/prop/direct/P2684'), ('propertyName', 'Kijkwijzer rating')]
# [('property', 'http://www.wikidata.org/prop/direct/P3673'), ('propertyName', 'film-documentaire.fr film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4277'), ('propertyName', 'Daum movie ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5311'), ('propertyName', 'Kino-teatr.ua film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5338'), ('propertyName', 'SilentEra.com film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5990'), ('propertyName', 'Movies Anywhere ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P9215'), ('propertyName', 'set during recurring event')]
# [('property', 'http://www.wikidata.org/prop/direct/P2678'), ('propertyName', 'Russiancinema.ru film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3174'), ('propertyName', 'art director')]
# [('property', 'http://www.wikidata.org/prop/direct/P7741'), ('propertyName', 'IDFA film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3367'), ('propertyName', 'GECD film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6658'), ('propertyName', 'RCQ classification')]
# [('property', 'http://www.wikidata.org/prop/direct/P2970'), ('propertyName', 'Kinopolis film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3216'), ('propertyName', 'ClassInd rating')]
# [('property', 'http://www.wikidata.org/prop/direct/P8958'), ('propertyName', 'ClassInd audiovisual work ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6256'), ('propertyName', 'SinemaTürk film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2637'), ('propertyName', 'RARS rating')]
# [('property', 'http://www.wikidata.org/prop/direct/P7611'), ('propertyName', 'Taiwan Cinema film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P10'), ('propertyName', 'video')]
# [('property', 'http://www.wikidata.org/prop/direct/P1343'), ('propertyName', 'described by source')]
# [('property', 'http://www.wikidata.org/prop/direct/P1411'), ('propertyName', 'nominated for')]
# [('property', 'http://www.wikidata.org/prop/direct/P275'), ('propertyName', 'copyright license')]
# [('property', 'http://www.wikidata.org/prop/direct/P3961'), ('propertyName', 'Unifrance film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4515'), ('propertyName', 'Prisma ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4786'), ('propertyName', 'cinematografo film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P527'), ('propertyName', 'has part')]
# [('property', 'http://www.wikidata.org/prop/direct/P6145'), ('propertyName', 'Academy Awards Database film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P674'), ('propertyName', 'characters')]
# [('property', 'http://www.wikidata.org/prop/direct/P8796'), ('propertyName', 'FilmPolski press collection ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P973'), ('propertyName', 'described at URL')]
# [('property', 'http://www.wikidata.org/prop/direct/P3579'), ('propertyName', 'Sina Weibo user ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3931'), ('propertyName', 'copyright holder')]
# [('property', 'http://www.wikidata.org/prop/direct/P5028'), ('propertyName', 'sound designer')]
# [('property', 'http://www.wikidata.org/prop/direct/P2400'), ('propertyName', 'JMDb film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5126'), ('propertyName', 'assistant director')]
# [('property', 'http://www.wikidata.org/prop/direct/P3821'), ('propertyName', 'Bangla Movie Database ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3868'), ('propertyName', 'MyDramaList title ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3704'), ('propertyName', 'KMDb film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5108'), ('propertyName', 'HanCinema film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1651'), ('propertyName', 'YouTube video ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2747'), ('propertyName', 'Filmiroda rating')]
# [('property', 'http://www.wikidata.org/prop/direct/P571'), ('propertyName', 'inception')]
# [('property', 'http://www.wikidata.org/prop/direct/P724'), ('propertyName', 'Internet Archive ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7334'), ('propertyName', 'Vudu video ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3803'), ('propertyName', 'original film format')]
# [('property', 'http://www.wikidata.org/prop/direct/P7003'), ('propertyName', 'ACMI web ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3139'), ('propertyName', 'SourehCinema film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2756'), ('propertyName', 'EIRIN film rating')]
# [('property', 'http://www.wikidata.org/prop/direct/P2826'), ('propertyName', 'Megogo ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1439'), ('propertyName', 'Norwegian filmography ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2438'), ('propertyName', 'narrator')]
# [('property', 'http://www.wikidata.org/prop/direct/P6359'), ('propertyName', 'Crew United title ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6549'), ('propertyName', 'NZ On Screen work ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4437'), ('propertyName', 'FPB rating')]
# [('property', 'http://www.wikidata.org/prop/direct/P5860'), ('propertyName', 'AnimeClick drama ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P180'), ('propertyName', 'depicts')]
# [('property', 'http://www.wikidata.org/prop/direct/P3495'), ('propertyName', 'FilmPolski.pl ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P407'), ('propertyName', 'language of work or name')]
# [('property', 'http://www.wikidata.org/prop/direct/P5233'), ('propertyName', 'Filmow ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P585'), ('propertyName', 'point in time')]
# [('property', 'http://www.wikidata.org/prop/direct/P641'), ('propertyName', 'sport')]
# [('property', 'http://www.wikidata.org/prop/direct/P6839'), ('propertyName', 'TV Tropes identifier')]
# [('property', 'http://www.wikidata.org/prop/direct/P7212'), ('propertyName', 'LyricsTranslate ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7299'), ('propertyName', 'MUBI film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4933'), ('propertyName', 'Big Cartoon Database ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6133'), ('propertyName', 'Siamzone film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7975'), ('propertyName', 'Filmfront film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4608'), ('propertyName', 'scenographer')]
# [('property', 'http://www.wikidata.org/prop/direct/P6458'), ('propertyName', 'Mtime movie ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P8889'), ('propertyName', 'MTRCB rating')]
# [('property', 'http://www.wikidata.org/prop/direct/P361'), ('propertyName', 'part of')]
# [('property', 'http://www.wikidata.org/prop/direct/P3818'), ('propertyName', 'KMRB film rating')]
# [('property', 'http://www.wikidata.org/prop/direct/P138'), ('propertyName', 'named after')]
# [('property', 'http://www.wikidata.org/prop/direct/P4835'), ('propertyName', 'TheTVDB.com series ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P50'), ('propertyName', 'author')]
# [('property', 'http://www.wikidata.org/prop/direct/P7222'), ('propertyName', 'Eiga.com movie ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7936'), ('propertyName', 'business model')]
# [('property', 'http://www.wikidata.org/prop/direct/P8013'), ('propertyName', 'Trakt.tv ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P8383'), ('propertyName', 'Goodreads work ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P212'), ('propertyName', 'ISBN-13')]
# [('property', 'http://www.wikidata.org/prop/direct/P3854'), ('propertyName', 'Soundtrack Collector ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P406'), ('propertyName', 'soundtrack release')]
# [('property', 'http://www.wikidata.org/prop/direct/P7177'), ('propertyName', 'Cinestaan film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2969'), ('propertyName', 'Goodreads version/edition ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3851'), ('propertyName', 'Cinenacional.com movie ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3383'), ('propertyName', 'film poster')]
# [('property', 'http://www.wikidata.org/prop/direct/P4513'), ('propertyName', 'Africultures movie ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6195'), ('propertyName', 'funding scheme')]
# [('property', 'http://www.wikidata.org/prop/direct/P1104'), ('propertyName', 'number of pages')]
# [('property', 'http://www.wikidata.org/prop/direct/P135'), ('propertyName', 'movement')]
# [('property', 'http://www.wikidata.org/prop/direct/P1729'), ('propertyName', 'AllMusic album ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1814'), ('propertyName', 'name in kana')]
# [('property', 'http://www.wikidata.org/prop/direct/P1954'), ('propertyName', 'Discogs master ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P214'), ('propertyName', 'VIAF ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P227'), ('propertyName', 'GND ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P244'), ('propertyName', 'Library of Congress authority ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P264'), ('propertyName', 'record label')]
# [('property', 'http://www.wikidata.org/prop/direct/P268'), ('propertyName', 'Bibliothèque nationale de France ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3414'), ('propertyName', 'Yle Areena item ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P460'), ('propertyName', 'said to be the same as')]
# [('property', 'http://www.wikidata.org/prop/direct/P5732'), ('propertyName', 'bgm.tv subject ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7937'), ('propertyName', 'form of creative work')]
# [('property', 'http://www.wikidata.org/prop/direct/P1191'), ('propertyName', 'date of first performance')]
# [('property', 'http://www.wikidata.org/prop/direct/P4647'), ('propertyName', 'location of first performance')]
# [('property', 'http://www.wikidata.org/prop/direct/P8856'), ('propertyName', 'British Phonographic Industry ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1985'), ('propertyName', 'Anime News Network anime ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5646'), ('propertyName', 'AniDB anime ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5845'), ('propertyName', 'AnimeClick anime ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P9205'), ('propertyName', 'Sinemalar title ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5201'), ('propertyName', 'IMDA rating')]
# [('property', 'http://www.wikidata.org/prop/direct/P7285'), ('propertyName', 'Writers Guild of America project ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P8918'), ('propertyName', 'Max Movie film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P9146'), ('propertyName', 'CITWF title ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6932'), ('propertyName', 'RogerEbert.com film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P9203'), ('propertyName', 'CineFAN.ro title ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P9204'), ('propertyName', 'CinemaRX title ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1344'), ('propertyName', 'participant in')]
# [('property', 'http://www.wikidata.org/prop/direct/P2581'), ('propertyName', 'BabelNet ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3110'), ('propertyName', 'ISzDb film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4839'), ('propertyName', 'Wolfram Language entity code')]
# [('property', 'http://www.wikidata.org/prop/direct/P5253'), ('propertyName', 'FilmTv.it movie ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5693'), ('propertyName', 'Fandango film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6181'), ('propertyName', 'Disney A to Z ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7091'), ('propertyName', 'Common Sense Media ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7236'), ('propertyName', 'Dove.org work ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P8847'), ('propertyName', 'Kinorium movie ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7327'), ('propertyName', 'OFLC classification')]
# [('property', 'http://www.wikidata.org/prop/direct/P8680'), ('propertyName', 'FVLB work ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7340'), ('propertyName', 'sixpackfilmdata film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7118'), ('propertyName', 'AMPAS collections film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7978'), ('propertyName', 'Decine21 film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P8055'), ('propertyName', 'Amazon.com Prime Video ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5510'), ('propertyName', 'DEFA film database ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5865'), ('propertyName', 'IGN film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6383'), ('propertyName', 'TV Spielfilm film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6466'), ('propertyName', 'Hulu movie ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P9821'), ('propertyName', 'Unconsenting Media ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7573'), ('propertyName', 'IFCO rating')]
# [('property', 'http://www.wikidata.org/prop/direct/P4483'), ('propertyName', 'INDUCKS story ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3092'), ('propertyName', 'film crew member')]
# [('property', 'http://www.wikidata.org/prop/direct/P195'), ('propertyName', 'collection')]
# [('property', 'http://www.wikidata.org/prop/direct/P2003'), ('propertyName', 'Instagram username')]
# [('property', 'http://www.wikidata.org/prop/direct/P4342'), ('propertyName', 'Store norske leksikon ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6262'), ('propertyName', 'Fandom article ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6760'), ('propertyName', 'Know Your Meme ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7818'), ('propertyName', 'French Vikidia ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2014'), ('propertyName', 'Museum of Modern Art work ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5384'), ('propertyName', 'Behind The Voice Actors film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P725'), ('propertyName', 'voice actor')]
# [('property', 'http://www.wikidata.org/prop/direct/P2754'), ('propertyName', 'production date')]
# [('property', 'http://www.wikidata.org/prop/direct/P3943'), ('propertyName', 'Tumblr username')]
# [('property', 'http://www.wikidata.org/prop/direct/P8035'), ('propertyName', 'm3db.com film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4086'), ('propertyName', 'MyAnimeList anime ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P8729'), ('propertyName', 'AniList anime ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P444'), ('propertyName', 'review score')]
# [('property', 'http://www.wikidata.org/prop/direct/P449'), ('propertyName', 'original broadcaster')]
# [('property', 'http://www.wikidata.org/prop/direct/P9743'), ('propertyName', 'Podchaser creator ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3995'), ('propertyName', 'Filmweb.pl ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7595'), ('propertyName', 'Disney+ movie ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1273'), ('propertyName', 'CANTIC ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P269'), ('propertyName', 'IdRef ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P349'), ('propertyName', 'National Diet Library ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6058'), ('propertyName', 'Larousse ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P950'), ('propertyName', 'Biblioteca Nacional de España ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5495'), ('propertyName', 'Mormon Literature and Creative Arts Database Works ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1552'), ('propertyName', 'has quality')]
# [('property', 'http://www.wikidata.org/prop/direct/P2397'), ('propertyName', 'YouTube channel ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P8324'), ('propertyName', 'funder')]
# [('property', 'http://www.wikidata.org/prop/direct/P941'), ('propertyName', 'inspired by')]
# [('property', 'http://www.wikidata.org/prop/direct/P4805'), ('propertyName', 'make-up artist')]
# [('property', 'http://www.wikidata.org/prop/direct/P5791'), ('propertyName', 'Cineuropa film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6474'), ('propertyName', 'Swiss Films ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7458'), ('propertyName', 'Kinematoscope film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P9067'), ('propertyName', 'Hungarian Film Archive ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P170'), ('propertyName', 'creator')]
# [('property', 'http://www.wikidata.org/prop/direct/P2769'), ('propertyName', 'budget')]
# [('property', 'http://www.wikidata.org/prop/direct/P825'), ('propertyName', 'dedicated to')]
# [('property', 'http://www.wikidata.org/prop/direct/P6151'), ('propertyName', 'ANICA ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4969'), ('propertyName', 'derivative work')]
# [('property', 'http://www.wikidata.org/prop/direct/P7194'), ('propertyName', 'AZLyrics.com artist ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3428'), ('propertyName', 'INCAA film rating')]
# [('property', 'http://www.wikidata.org/prop/direct/P2613'), ('propertyName', 'TED talk ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4209'), ('propertyName', 'danskfilmogtv title ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2001'), ('propertyName', 'Revised Romanization')]
# [('property', 'http://www.wikidata.org/prop/direct/P217'), ('propertyName', 'inventory number')]
# [('property', 'http://www.wikidata.org/prop/direct/P243'), ('propertyName', 'OCLC control number')]
# [('property', 'http://www.wikidata.org/prop/direct/P276'), ('propertyName', 'location')]
# [('property', 'http://www.wikidata.org/prop/direct/P3785'), ('propertyName', 'danskefilm film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P9701'), ('propertyName', 'African Film Database ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2283'), ('propertyName', 'uses')]
# [('property', 'http://www.wikidata.org/prop/direct/P3301'), ('propertyName', 'broadcast by')]
# [('property', 'http://www.wikidata.org/prop/direct/P3553'), ('propertyName', 'Zhihu topic ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4013'), ('propertyName', 'Giphy username')]
# [('property', 'http://www.wikidata.org/prop/direct/P4983'), ('propertyName', 'TMDb TV series ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5357'), ('propertyName', 'The Encyclopedia of Science Fiction ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P580'), ('propertyName', 'start time')]
# [('property', 'http://www.wikidata.org/prop/direct/P582'), ('propertyName', 'end time')]
# [('property', 'http://www.wikidata.org/prop/direct/P1110'), ('propertyName', 'attendance')]
# [('property', 'http://www.wikidata.org/prop/direct/P7501'), ('propertyName', 'audio system')]
# [('property', 'http://www.wikidata.org/prop/direct/P8673'), ('propertyName', 'Naver movie ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6196'), ('propertyName', 'Badtaste ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P9086'), ('propertyName', 'BAMID film rating')]
# [('property', 'http://www.wikidata.org/prop/direct/P2364'), ('propertyName', 'production code')]
# [('property', 'http://www.wikidata.org/prop/direct/P5150'), ('propertyName', 'IGAC rating')]
# [('property', 'http://www.wikidata.org/prop/direct/P6643'), ('propertyName', 'TV Spielfilm series ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P8298'), ('propertyName', 'HBO Max ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5152'), ('propertyName', 'KAVI rating')]
# [('property', 'http://www.wikidata.org/prop/direct/P5318'), ('propertyName', 'César Award film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7293'), ('propertyName', 'PLWABN ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P8800'), ('propertyName', 'European Film Awards ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P949'), ('propertyName', 'National Library of Israel ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3787'), ('propertyName', 'danskefilm silent film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7132'), ('propertyName', 'ComingSoon.it film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1922'), ('propertyName', 'first line')]
# [('property', 'http://www.wikidata.org/prop/direct/P2512'), ('propertyName', 'series spin-off')]
# [('property', 'http://www.wikidata.org/prop/direct/P435'), ('propertyName', 'MusicBrainz work ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5008'), ('propertyName', 'on focus list of Wikimedia project')]
# [('property', 'http://www.wikidata.org/prop/direct/P747'), ('propertyName', 'has edition or translation')]
# [('property', 'http://www.wikidata.org/prop/direct/P8345'), ('propertyName', 'media franchise')]
# [('property', 'http://www.wikidata.org/prop/direct/P1680'), ('propertyName', 'subtitle')]
# [('property', 'http://www.wikidata.org/prop/direct/P1638'), ('propertyName', 'codename')]
# [('property', 'http://www.wikidata.org/prop/direct/P8920'), ('propertyName', 'Movist film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5395'), ('propertyName', 'Canadian Encyclopedia article ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5733'), ('propertyName', 'bilibili ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1015'), ('propertyName', 'NORAF ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1451'), ('propertyName', 'motto text')]
# [('property', 'http://www.wikidata.org/prop/direct/P1695'), ('propertyName', 'NLP ID (unique)')]
# [('property', 'http://www.wikidata.org/prop/direct/P1942'), ('propertyName', 'McCune-Reischauer romanization')]
# [('property', 'http://www.wikidata.org/prop/direct/P3265'), ('propertyName', 'Myspace ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3569'), ('propertyName', 'Cultureel Woordenboek ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5327'), ('propertyName', 'fernsehserien.de ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P8179'), ('propertyName', 'Canadiana NCF ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P9584'), ('propertyName', 'The Criterion Collection film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2360'), ('propertyName', 'intended public')]
# [('property', 'http://www.wikidata.org/prop/direct/P3219'), ('propertyName', 'Encyclopædia Universalis ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3794'), ('propertyName', 'Dictionary of Sydney ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P8885'), ('propertyName', 'Namuwiki ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2163'), ('propertyName', 'FAST ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P691'), ('propertyName', 'NKCR AUT ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3156'), ('propertyName', 'Australian Classification')]
# [('property', 'http://www.wikidata.org/prop/direct/P7760'), ('propertyName', 'Tubi movie ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7631'), ('propertyName', 'MPPDA Digital Archive film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P8874'), ('propertyName', 'Hong Kong film rating')]
# [('property', 'http://www.wikidata.org/prop/direct/P6900'), ('propertyName', 'NicoNicoPedia ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P767'), ('propertyName', 'contributor to the creative work or subject')]
# [('property', 'http://www.wikidata.org/prop/direct/P98'), ('propertyName', 'editor')]
# [('property', 'http://www.wikidata.org/prop/direct/P3222'), ('propertyName', 'NE.se ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6802'), ('propertyName', 'related image')]
# [('property', 'http://www.wikidata.org/prop/direct/P8189'), ('propertyName', 'National Library of Israel J9U ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P827'), ('propertyName', 'BBC programme ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5749'), ('propertyName', 'Amazon Standard Identification Number')]
# [('property', 'http://www.wikidata.org/prop/direct/P935'), ('propertyName', 'Commons gallery')]
# [('property', 'http://www.wikidata.org/prop/direct/P1813'), ('propertyName', 'short name')]
# [('property', 'http://www.wikidata.org/prop/direct/P528'), ('propertyName', 'catalog code')]
# [('property', 'http://www.wikidata.org/prop/direct/P7512'), ('propertyName', 'startrek.com Database ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P800'), ('propertyName', 'notable work')]
# [('property', 'http://www.wikidata.org/prop/direct/P483'), ('propertyName', 'recorded at studio or venue')]
# [('property', 'http://www.wikidata.org/prop/direct/P942'), ('propertyName', 'theme music')]
# [('property', 'http://www.wikidata.org/prop/direct/P5940'), ('propertyName', 'plot expanded in')]
# [('property', 'http://www.wikidata.org/prop/direct/P7892'), ('propertyName', 'EFIS film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P953'), ('propertyName', 'full work available at URL')]
# [('property', 'http://www.wikidata.org/prop/direct/P5083'), ('propertyName', 'Adult Film Database film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5098'), ('propertyName', 'IAFD film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P972'), ('propertyName', 'catalog')]
# [('property', 'http://www.wikidata.org/prop/direct/P2437'), ('propertyName', 'number of seasons')]
# [('property', 'http://www.wikidata.org/prop/direct/P371'), ('propertyName', 'presenter')]
# [('property', 'http://www.wikidata.org/prop/direct/P5925'), ('propertyName', 'Moviepilot.de series ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1219'), ('propertyName', 'Internet Broadway Database show ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6166'), ('propertyName', 'quotes work')]
# [('property', 'http://www.wikidata.org/prop/direct/P2079'), ('propertyName', 'fabrication method')]
# [('property', 'http://www.wikidata.org/prop/direct/P3478'), ('propertyName', 'Songkick artist ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5885'), ('propertyName', 'Microsoft Store product ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2913'), ('propertyName', 'date depicted')]
# [('property', 'http://www.wikidata.org/prop/direct/P5829'), ('propertyName', 'Television Academy Foundation show ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P8674'), ('propertyName', 'Bollywood Hungama movie ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3906'), ('propertyName', 'Ishim ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P9022'), ('propertyName', 'Mediafilm ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3445'), ('propertyName', 'Cinema of Israel ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5151'), ('propertyName', 'Israel Film Fund ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2860'), ('propertyName', 'cites work')]
# [('property', 'http://www.wikidata.org/prop/direct/P4300'), ('propertyName', 'YouTube playlist ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P9322'), ('propertyName', 'SVKKL authority ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P8670'), ('propertyName', 'character designer')]
# [('property', 'http://www.wikidata.org/prop/direct/P123'), ('propertyName', 'publisher')]
# [('property', 'http://www.wikidata.org/prop/direct/P4073'), ('propertyName', 'Fandom wiki ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5820'), ('propertyName', 'Film Indonesia ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P957'), ('propertyName', 'ISBN-10')]
# [('property', 'http://www.wikidata.org/prop/direct/P6134'), ('propertyName', 'Thaifilm ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5218'), ('propertyName', 'Armenian Cinema ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4021'), ('propertyName', 'danskefilm animated film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4953'), ('propertyName', 'Library of Congress Genre/Form Terms ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7679'), ('propertyName', 'Cinépolis KLIC ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P8895'), ('propertyName', 'All the Tropes identifier')]
# [('property', 'http://www.wikidata.org/prop/direct/P5146'), ('propertyName', 'Cinema Project (Israel) ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3308'), ('propertyName', 'lib.reviews ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P737'), ('propertyName', 'influenced by')]
# [('property', 'http://www.wikidata.org/prop/direct/P2849'), ('propertyName', 'produced by')]
# [('property', 'http://www.wikidata.org/prop/direct/P2572'), ('propertyName', 'hashtag')]
# [('property', 'http://www.wikidata.org/prop/direct/P3185'), ('propertyName', 'VK ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P360'), ('propertyName', 'is a list of')]
# [('property', 'http://www.wikidata.org/prop/direct/P7775'), ('propertyName', 'RationalWiki ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P8371'), ('propertyName', 'references work, tradition or theory')]
# [('property', 'http://www.wikidata.org/prop/direct/P5337'), ('propertyName', 'Google News topics ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P8408'), ('propertyName', 'KBpedia ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P989'), ('propertyName', 'spoken text audio')]
# [('property', 'http://www.wikidata.org/prop/direct/P3589'), ('propertyName', 'GCD series ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2897'), ('propertyName', 'Eldoblaje Movie ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6942'), ('propertyName', 'animator')]
# [('property', 'http://www.wikidata.org/prop/direct/P8908'), ('propertyName', 'CINE21 film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P8921'), ('propertyName', 'KOBIS ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1207'), ('propertyName', 'NUKAT ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1375'), ('propertyName', 'NSK ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2387'), ('propertyName', 'Elonet person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P178'), ('propertyName', 'developer')]
# [('property', 'http://www.wikidata.org/prop/direct/P400'), ('propertyName', 'platform')]
# [('property', 'http://www.wikidata.org/prop/direct/P1435'), ('propertyName', 'heritage designation')]
# [('property', 'http://www.wikidata.org/prop/direct/P4431'), ('propertyName', 'Google Doodle')]
# [('property', 'http://www.wikidata.org/prop/direct/P551'), ('propertyName', 'residence')]
# [('property', 'http://www.wikidata.org/prop/direct/P3893'), ('propertyName', 'public domain date')]
# [('property', 'http://www.wikidata.org/prop/direct/P5707'), ('propertyName', 'samples from work')]
# [('property', 'http://www.wikidata.org/prop/direct/P3106'), ('propertyName', 'Guardian topic ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5555'), ('propertyName', 'schematic')]
# [('property', 'http://www.wikidata.org/prop/direct/P6817'), ('propertyName', 'SVT Play ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4082'), ('propertyName', 'captured with')]
# [('property', 'http://www.wikidata.org/prop/direct/P3113'), ('propertyName', 'does not have part')]
# [('property', 'http://www.wikidata.org/prop/direct/P3816'), ('propertyName', 'film script')]
# [('property', 'http://www.wikidata.org/prop/direct/P6657'), ('propertyName', 'CHVRS Classification')]
# [('property', 'http://www.wikidata.org/prop/direct/P1267'), ('propertyName', 'AlloCiné series ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1430'), ('propertyName', 'OpenPlaques subject ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1617'), ('propertyName', 'BBC Things ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P9281'), ('propertyName', 'Encyclopedia of Greater Philadelphia ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3275'), ('propertyName', 'storyboard artist')]
# [('property', 'http://www.wikidata.org/prop/direct/P4110'), ('propertyName', 'Crunchyroll ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P9760'), ('propertyName', "Treccani's Enciclopedia del Cinema ID")]
# [('property', 'http://www.wikidata.org/prop/direct/P2475'), ('propertyName', 'NAVA ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P990'), ('propertyName', "audio recording of the subject's spoken voice")]
# [('property', 'http://www.wikidata.org/prop/direct/P8295'), ('propertyName', 'AustLit ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2206'), ('propertyName', 'Discogs release ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6962'), ('propertyName', 'narrative motif')]
# [('property', 'http://www.wikidata.org/prop/direct/P1441'), ('propertyName', 'present in work')]
# [('property', 'http://www.wikidata.org/prop/direct/P4845'), ('propertyName', 'Bulbapedia article')]
# [('property', 'http://www.wikidata.org/prop/direct/P6992'), ('propertyName', 'IMFDB ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3365'), ('propertyName', 'Treccani ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7952'), ('propertyName', 'The First Amendment Encyclopedia ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3218'), ('propertyName', 'Auñamendi ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1296'), ('propertyName', 'Gran Enciclopèdia Catalana ID')]
# ...
# [('property', 'http://www.wikidata.org/prop/direct/P8823'), ('propertyName', 'Xfinity Stream ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7204'), ('propertyName', 'Mafab.hu film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P8600'), ('propertyName', 'TV Maze series ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1036'), ('propertyName', 'Dewey Decimal Classification')]
# [('property', 'http://www.wikidata.org/prop/direct/P8359'), ('propertyName', 'Dewey Decimal Classification (works and editions)')]
# [('property', 'http://www.wikidata.org/prop/direct/P4784'), ('propertyName', 'Movieplayer TV-series ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5247'), ('propertyName', 'Giant Bomb ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P805'), ('propertyName', 'statement is subject of')]
# [('property', 'http://www.wikidata.org/prop/direct/P5255'), ('propertyName', 'FilmTv.it TV series ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2048'), ('propertyName', 'height')]
# [('property', 'http://www.wikidata.org/prop/direct/P2984'), ('propertyName', 'Snapchat username')]
# [('property', 'http://www.wikidata.org/prop/direct/P9186'), ('propertyName', 'DicoPolHiS ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1325'), ('propertyName', 'external data available at')]
# [('property', 'http://www.wikidata.org/prop/direct/P6738'), ('propertyName', 'Whitney Museum of American Art artwork ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P971'), ('propertyName', 'category combines topics')]
# [('property', 'http://www.wikidata.org/prop/direct/P1659'), ('propertyName', 'see also')]
# [('property', 'http://www.wikidata.org/prop/direct/P611'), ('propertyName', 'religious order')]
# [('property', 'http://www.wikidata.org/prop/direct/P1366'), ('propertyName', 'replaced by')]
# [('property', 'http://www.wikidata.org/prop/direct/P3999'), ('propertyName', 'date of official closure')]
# [('property', 'http://www.wikidata.org/prop/direct/P2789'), ('propertyName', 'connects with')]
# [('property', 'http://www.wikidata.org/prop/direct/P2089'), ('propertyName', 'Library of Congress JukeBox ID (former scheme)')]
# [('property', 'http://www.wikidata.org/prop/direct/P6603'), ('propertyName', 'film-documentaire.fr author ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6366'), ('propertyName', 'Microsoft Academic ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1037'), ('propertyName', 'director / manager')]
# [('property', 'http://www.wikidata.org/prop/direct/P2908'), ('propertyName', 'SecondHandSongs work ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6218'), ('propertyName', 'Genius song ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6010'), ('propertyName', 'Encyclopedia of Alabama ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4404'), ('propertyName', 'MusicBrainz recording ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5813'), ('propertyName', 'MusicBrainz release ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6439'), ('propertyName', 'has lyrics')]
# [('property', 'http://www.wikidata.org/prop/direct/P7211'), ('propertyName', 'LINE BLOG user ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6476'), ('propertyName', 'castingvideos ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2550'), ('propertyName', 'recording or performance of')]
# [('property', 'http://www.wikidata.org/prop/direct/P4254'), ('propertyName', 'Bengali Banglapedia ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P902'), ('propertyName', 'HDS ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5909'), ('propertyName', 'HKCAN ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P19'), ('propertyName', 'place of birth')]
# [('property', 'http://www.wikidata.org/prop/direct/P6464'), ('propertyName', 'Mtime people ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6367'), ('propertyName', "Bahamut Gamer's Community ACG Database ID")]
# [('property', 'http://www.wikidata.org/prop/direct/P2942'), ('propertyName', 'Dailymotion channel ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P569'), ('propertyName', 'date of birth')]
# [('property', 'http://www.wikidata.org/prop/direct/P9848'), ('propertyName', 'Cinemaitaliano film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P9318'), ('propertyName', 'Ávvir topic ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1297'), ('propertyName', 'IRS Employer Identification Number')]
# [('property', 'http://www.wikidata.org/prop/direct/P4861'), ('propertyName', 'Charity Navigator ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1705'), ('propertyName', 'native label')]
# [('property', 'http://www.wikidata.org/prop/direct/P3136'), ('propertyName', 'elCinema person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6554'), ('propertyName', 'Represent Me ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P306'), ('propertyName', 'operating system')]
# [('property', 'http://www.wikidata.org/prop/direct/P404'), ('propertyName', 'game mode')]
# [('property', 'http://www.wikidata.org/prop/direct/P479'), ('propertyName', 'input method')]
# [('property', 'http://www.wikidata.org/prop/direct/P7335'), ('propertyName', 'Mixer game ID (former scheme)')]
# [('property', 'http://www.wikidata.org/prop/direct/P1733'), ('propertyName', 'Steam application ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P600'), ('propertyName', 'Wine AppDB ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6337'), ('propertyName', 'PCGamingWiki ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4527'), ('propertyName', 'UK Parliament thesaurus ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6679'), ('propertyName', 'Encyklopedia Teatru Polskiego play ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P106'), ('propertyName', 'occupation')]
# [('property', 'http://www.wikidata.org/prop/direct/P5882'), ('propertyName', 'Muziekweb performer ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P176'), ('propertyName', 'manufacturer')]
# [('property', 'http://www.wikidata.org/prop/direct/P41'), ('propertyName', 'flag image')]
# [('property', 'http://www.wikidata.org/prop/direct/P2960'), ('propertyName', 'archive date')]
# [('property', 'http://www.wikidata.org/prop/direct/P4970'), ('propertyName', 'alternate names')]
# [('property', 'http://www.wikidata.org/prop/direct/P4779'), ('propertyName', 'MYmovies actor ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2236'), ('propertyName', 'external subproperty')]
# [('property', 'http://www.wikidata.org/prop/direct/P2049'), ('propertyName', 'width')]
# [('property', 'http://www.wikidata.org/prop/direct/P2386'), ('propertyName', 'diameter')]
# [('property', 'http://www.wikidata.org/prop/direct/P8001'), ('propertyName', 'endorsed by')]
# [('property', 'http://www.wikidata.org/prop/direct/P7175'), ('propertyName', 'Gaana.com album ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P51'), ('propertyName', 'audio')]
# [('property', 'http://www.wikidata.org/prop/direct/P9863'), ('propertyName', 'Gujarati Vishwakosh entry')]
# [('property', 'http://www.wikidata.org/prop/direct/P5505'), ('propertyName', 'WorldCat Registry ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P21'), ('propertyName', 'sex or gender')]
# [('property', 'http://www.wikidata.org/prop/direct/P508'), ('propertyName', 'BNCF Thesaurus ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1132'), ('propertyName', 'number of participants')]
# [('property', 'http://www.wikidata.org/prop/direct/P1350'), ('propertyName', 'number of matches played/races/starts')]
# [('property', 'http://www.wikidata.org/prop/direct/P393'), ('propertyName', 'edition number')]
# [('property', 'http://www.wikidata.org/prop/direct/P4643'), ('propertyName', 'Philadelphia Museum of Art work ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7685'), ('propertyName', 'CALS Encyclopedia of Arkansas ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1707'), ('propertyName', 'DAAO ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3575'), ('propertyName', 'data size')]
# [('property', 'http://www.wikidata.org/prop/direct/P4701'), ('propertyName', 'Google Arts & Culture asset ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6467'), ('propertyName', 'Hulu series ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1449'), ('propertyName', 'nickname')]
# [('property', 'http://www.wikidata.org/prop/direct/P6175'), ('propertyName', 'Bitraga work ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2011'), ('propertyName', 'Cooper-Hewitt Person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P27'), ('propertyName', 'country of citizenship')]
# [('property', 'http://www.wikidata.org/prop/direct/P3293'), ('propertyName', 'BALaT object ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7704'), ('propertyName', 'Europeana entity')]
# [('property', 'http://www.wikidata.org/prop/direct/P2032'), ('propertyName', 'work period (end)')]
# [('property', 'http://www.wikidata.org/prop/direct/P4769'), ('propertyName', 'GameFAQs game ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7117'), ('propertyName', 'Media Arts Database console games ID (former scheme)')]
# [('property', 'http://www.wikidata.org/prop/direct/P576'), ('propertyName', 'dissolved, abolished or demolished date')]
# [('property', 'http://www.wikidata.org/prop/direct/P452'), ('propertyName', 'industry')]
# [('property', 'http://www.wikidata.org/prop/direct/P1766'), ('propertyName', 'place name sign')]
# [('property', 'http://www.wikidata.org/prop/direct/P547'), ('propertyName', 'commemorates')]
# [('property', 'http://www.wikidata.org/prop/direct/P2354'), ('propertyName', 'has list')]
# [('property', 'http://www.wikidata.org/prop/direct/P2407'), ('propertyName', 'short-term exposure limit')]
# [('property', 'http://www.wikidata.org/prop/direct/P7839'), ('propertyName', 'Saregama artist ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4683'), ('propertyName', 'National Gallery of Art artwork ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3065'), ('propertyName', 'RERO ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7932'), ('propertyName', 'Irish playography play ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7228'), ('propertyName', 'access restriction status')]
# [('property', 'http://www.wikidata.org/prop/direct/P6081'), ('propertyName', 'RIA Novosti reference')]
# [('property', 'http://www.wikidata.org/prop/direct/P8708'), ('propertyName', 'Danish educational institution number')]
# [('property', 'http://www.wikidata.org/prop/direct/P6868'), ('propertyName', 'Hoopla artist ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5290'), ('propertyName', 'Redump.org ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6368'), ('propertyName', 'Media Arts Database anime ID (former scheme)')]
# [('property', 'http://www.wikidata.org/prop/direct/P4613'), ('propertyName', 'Encyclopedia of Modern Ukraine ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4656'), ('propertyName', 'Wikimedia import URL')]
# [('property', 'http://www.wikidata.org/prop/direct/P7555'), ('propertyName', 'UVL game ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6500'), ('propertyName', 'non-free artwork image URL')]
# [('property', 'http://www.wikidata.org/prop/direct/P1019'), ('propertyName', 'web feed URL')]
# [('property', 'http://www.wikidata.org/prop/direct/P5284'), ('propertyName', 'Douban movie celebrity ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P37'), ('propertyName', 'official language')]
# [('property', 'http://www.wikidata.org/prop/direct/P6524'), ('propertyName', 'expression of')]
# [('property', 'http://www.wikidata.org/prop/direct/P1051'), ('propertyName', 'PSH ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4765'), ('propertyName', 'Commons compatible image available at URL')]
# [('property', 'http://www.wikidata.org/prop/direct/P8349'), ('propertyName', 'Proleksis enciklopedija ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1612'), ('propertyName', 'Commons Institution page')]
# [('property', 'http://www.wikidata.org/prop/direct/P7596'), ('propertyName', 'Disney+ series ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7306'), ('propertyName', 'Downdetector ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7591'), ('propertyName', 'VideoGameGeek game ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1810'), ('propertyName', 'named as')]
# [('property', 'http://www.wikidata.org/prop/direct/P5204'), ('propertyName', 'date of commercialization')]
# [('property', 'http://www.wikidata.org/prop/direct/P1652'), ('propertyName', 'referee')]
# [('property', 'http://www.wikidata.org/prop/direct/P4330'), ('propertyName', 'contains')]
# [('property', 'http://www.wikidata.org/prop/direct/P1923'), ('propertyName', 'participating team')]
# [('property', 'http://www.wikidata.org/prop/direct/P2284'), ('propertyName', 'price')]
# [('property', 'http://www.wikidata.org/prop/direct/P1027'), ('propertyName', 'conferred by')]
# [('property', 'http://www.wikidata.org/prop/direct/P2670'), ('propertyName', 'has parts of the class')]
# [('property', 'http://www.wikidata.org/prop/direct/P6379'), ('propertyName', 'has works in the collection')]
# [('property', 'http://www.wikidata.org/prop/direct/P5833'), ('propertyName', 'Playbill production ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1346'), ('propertyName', 'winner')]
# [('property', 'http://www.wikidata.org/prop/direct/P2561'), ('propertyName', 'name')]
# [('property', 'http://www.wikidata.org/prop/direct/P8392'), ('propertyName', 'Rate Your Music release ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P8125'), ('propertyName', 'Fandango person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P9525'), ('propertyName', 'LMIC musician ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P453'), ('propertyName', 'character role')]
# [('property', 'http://www.wikidata.org/prop/direct/P1317'), ('propertyName', 'floruit')]
# [('property', 'http://www.wikidata.org/prop/direct/P1479'), ('propertyName', 'has contributing factor')]
# [('property', 'http://www.wikidata.org/prop/direct/P2701'), ('propertyName', 'file format')]
# [('property', 'http://www.wikidata.org/prop/direct/P1447'), ('propertyName', 'Sports-Reference.com Olympic athlete ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P54'), ('propertyName', 'member of sports team')]
# [('property', 'http://www.wikidata.org/prop/direct/P570'), ('propertyName', 'date of death')]
# [('property', 'http://www.wikidata.org/prop/direct/P69'), ('propertyName', 'educated at')]
# [('property', 'http://www.wikidata.org/prop/direct/P735'), ('propertyName', 'given name')]
# [('property', 'http://www.wikidata.org/prop/direct/P8286'), ('propertyName', 'Olympedia people ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4985'), ('propertyName', 'TMDb person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3030'), ('propertyName', 'sheet music')]
# [('property', 'http://www.wikidata.org/prop/direct/P1752'), ('propertyName', 'scale')]
# [('property', 'http://www.wikidata.org/prop/direct/P5063'), ('propertyName', 'Interlingual Index ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P8814'), ('propertyName', 'WordNet 3.1 Synset ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1256'), ('propertyName', 'Iconclass notation')]
# [('property', 'http://www.wikidata.org/prop/direct/P2088'), ('propertyName', 'Crunchbase organization ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2959'), ('propertyName', 'permanent duplicated item')]
# [('property', 'http://www.wikidata.org/prop/direct/P1246'), ('propertyName', 'patent number')]
# [('property', 'http://www.wikidata.org/prop/direct/P6517'), ('propertyName', 'WhoSampled artist ID')]
# 924

# %%
#Return all properties that relates an entity of type film to Paul Auster
queryString = """
SELECT DISTINCT ?property ?propertyName
WHERE {

    # ?film wdt:P31 wd:Q11424.
    # ?film ?property wd:Q214642.
    # ?property <http://schema.org/name> ?propertyName.
}
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('property', 'http://www.wikidata.org/prop/direct/P161'), ('propertyName', 'cast member')]
# [('property', 'http://www.wikidata.org/prop/direct/P162'), ('propertyName', 'producer')]
# [('property', 'http://www.wikidata.org/prop/direct/P170'), ('propertyName', 'creator')]
# [('property', 'http://www.wikidata.org/prop/direct/P57'), ('propertyName', 'director')]
# [('property', 'http://www.wikidata.org/prop/direct/P58'), ('propertyName', 'screenwriter')]
# 5

# %%
#Return all properties that relates an entity of type film to Ian McEwan
queryString = """
SELECT DISTINCT ?property ?propertyName
WHERE {

    # ?film wdt:P31 wd:Q11424.
    # ?film ?property wd:Q190379.
    # ?property <http://schema.org/name> ?propertyName.
}
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('property', 'http://www.wikidata.org/prop/direct/P161'), ('propertyName', 'cast member')]
# [('property', 'http://www.wikidata.org/prop/direct/P162'), ('propertyName', 'producer')]
# [('property', 'http://www.wikidata.org/prop/direct/P58'), ('propertyName', 'screenwriter')]
# [('property', 'http://www.wikidata.org/prop/direct/P1877'), ('propertyName', 'after a work by')]
# 4

# %%
#Return relations between authors and films
queryString = """
SELECT DISTINCT ?author ?propertyName  ?filmTitle
WHERE {
    
    # ?film wdt:P31 wd:Q11424.
    # ?film wdt:P1476 ?filmTitle.
    
    {
        # ?film ?property wd:Q214642.
        wd:Q214642 wdt:P1559 ?author.
    }
    UNION
    {
        # ?film ?property wd:Q190379.
        wd:Q190379 wdt:P1559 ?author.
    }
    
    # ?property <http://schema.org/name> ?propertyName.
    
    FILTER(?property = wdt:P162 || ?property = wdt:P161 || ?property = wdt:P57 || ?property = wdt:P58)
}
ORDER BY ?filmTitle
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('author', 'Paul Auster'), ('propertyName', 'screenwriter'), ('filmTitle', 'Act of God')]
# [('author', 'Paul Auster'), ('propertyName', 'cast member'), ('filmTitle', 'Act of God')]
# [('author', 'Ian McEwan'), ('propertyName', 'producer'), ('filmTitle', 'Atonement')]
# [('author', 'Ian McEwan'), ('propertyName', 'screenwriter'), ('filmTitle', 'Atonement')]
# [('author', 'Paul Auster'), ('propertyName', 'screenwriter'), ('filmTitle', 'Blue in the Face')]
# [('author', 'Paul Auster'), ('propertyName', 'director'), ('filmTitle', 'Blue in the Face')]
# [('author', 'Ian McEwan'), ('propertyName', 'screenwriter'), ('filmTitle', 'Enduring Love')]
# [('author', 'Paul Auster'), ('propertyName', 'screenwriter'), ('filmTitle', 'Lulu on the Bridge')]
# [('author', 'Paul Auster'), ('propertyName', 'director'), ('filmTitle', 'Lulu on the Bridge')]
# [('author', 'Ian McEwan'), ('propertyName', 'screenwriter'), ('filmTitle', 'On Chesil Beach')]
# [('author', 'Paul Auster'), ('propertyName', 'screenwriter'), ('filmTitle', 'Smoke')]
# [('author', 'Paul Auster'), ('propertyName', 'director'), ('filmTitle', 'Smoke')]
# [('author', 'Ian McEwan'), ('propertyName', 'screenwriter'), ('filmTitle', 'The Cement Garden')]
# [('author', 'Paul Auster'), ('propertyName', 'screenwriter'), ('filmTitle', 'The Center of the World')]
# [('author', 'Ian McEwan'), ('propertyName', 'screenwriter'), ('filmTitle', 'The Children Act')]
# [('author', 'Ian McEwan'), ('propertyName', 'screenwriter'), ('filmTitle', 'The Comfort of Strangers')]
# [('author', 'Ian McEwan'), ('propertyName', 'screenwriter'), ('filmTitle', 'The Good Son')]
# [('author', 'Paul Auster'), ('propertyName', 'producer'), ('filmTitle', 'The Inner Life of Martin Frost')]
# [('author', 'Paul Auster'), ('propertyName', 'director'), ('filmTitle', 'The Inner Life of Martin Frost')]
# [('author', 'Paul Auster'), ('propertyName', 'screenwriter'), ('filmTitle', 'The Inner Life of Martin Frost')]
# [('author', 'Ian McEwan'), ('propertyName', 'screenwriter'), ('filmTitle', 'The Innocent')]
# [('author', 'Paul Auster'), ('propertyName', 'cast member'), ('filmTitle', 'The Music of Chance')]
# [('author', 'Paul Auster'), ('propertyName', 'screenwriter'), ('filmTitle', 'The Music of Chance')]
# [('author', 'Ian McEwan'), ('propertyName', 'screenwriter'), ('filmTitle', "The Ploughman's Lunch")]
# [('author', 'Ian McEwan'), ('propertyName', 'cast member'), ('filmTitle', 'The Unbelievers')]
# 25

# %%
#Did the authors produced, acted or directed a film?  If so, did they write the screenplay?
queryString = """

SELECT DISTINCT ?author ?propertyName  ?filmTitle (GROUP_CONCAT(?screenwriterName; separator="; ") AS ?screenwriters)
WHERE {

    # ?film wdt:P31 wd:Q11424.
    # ?film wdt:P1476 ?filmTitle.

    {
        # ?film ?property wd:Q214642.
        wd:Q214642 wdt:P1559 ?author.
    }
    UNION
    {
        # ?film ?property wd:Q190379.
        wd:Q190379 wdt:P1559 ?author.
    }

    # ?property <http://schema.org/name> ?propertyName.
    FILTER(?property = wdt:P162 || ?property = wdt:P161 || ?property = wdt:P57)
    
    # ?film wdt:P58 ?screenwriter.
    # ?screenwriter wdt:P1559 ?screenwriterName.

}

ORDER BY ?author
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('author', 'Ian McEwan'), ('propertyName', 'cast member'), ('filmTitle', 'The Unbelievers'), ('screenwriters', 'Lawrence Maxwell Krauss')]
# [('author', 'Ian McEwan'), ('propertyName', 'producer'), ('filmTitle', 'Atonement'), ('screenwriters', 'Christopher Hampton; Ian McEwan')]
# [('author', 'Paul Auster'), ('propertyName', 'producer'), ('filmTitle', 'The Inner Life of Martin Frost'), ('screenwriters', 'Paul Auster')]
# [('author', 'Paul Auster'), ('propertyName', 'director'), ('filmTitle', 'Smoke'), ('screenwriters', 'Paul Auster')]
# [('author', 'Paul Auster'), ('propertyName', 'director'), ('filmTitle', 'Lulu on the Bridge'), ('screenwriters', 'Paul Auster; Mira Sorvino; Willem Dafoe; Harvey Keitel; Vanessa Redgrave; Gina Gershon')]
# [('author', 'Paul Auster'), ('propertyName', 'director'), ('filmTitle', 'The Inner Life of Martin Frost'), ('screenwriters', 'Paul Auster')]
# [('author', 'Paul Auster'), ('propertyName', 'director'), ('filmTitle', 'Blue in the Face'), ('screenwriters', 'Paul Auster')]
# [('author', 'Paul Auster'), ('propertyName', 'cast member'), ('filmTitle', 'Act of God'), ('screenwriters', 'Paul Auster')]
# [('author', 'Paul Auster'), ('propertyName', 'cast member'), ('filmTitle', 'The Music of Chance'), ('screenwriters', 'Paul Auster')]
# 9

# %% [markdown]
# #### Point 3 Finish
# DESCRIPTION: First, I checked all the properties of an instance of “creativeWork” and then I checked which relationships connect a “creativeWork” to a “writtenWork” and vice versa.
# Because I didn’t find anything interesting, I deiced to check all nodes connected to an instance of a “creativeWork”.
# After having found the class “film” I searched for all the relationships that connects Paul Auster and Ian McEwan to an instance of film without any success.
# Then I tried the inverse relation, and I found all the properties in which I was interested.
#
#
# RESULT: The result shows that Paul Auster was involved in more films that Ian. Both have been screenwriter and producer for at least one film.

# %% [markdown]
# #### Point 4 Start

# %%
#Return all properties connecting "Written works objects" to "film" objects
queryString = """
SELECT DISTINCT ?property ?propertyName
WHERE {
    
    # ?writtenWork wdt:P31 wd:Q47461344.
    # ?film wdt:P31 wd:Q11424.
    
    # ?writtenWork ?property ?film.
    # ?property <http://schema.org/name> ?propertyName.
    
}

"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('property', 'http://www.wikidata.org/prop/direct/P156'), ('propertyName', 'followed by')]
# [('property', 'http://www.wikidata.org/prop/direct/P1889'), ('propertyName', 'different from')]
# [('property', 'http://www.wikidata.org/prop/direct/P4969'), ('propertyName', 'derivative work')]
# [('property', 'http://www.wikidata.org/prop/direct/P921'), ('propertyName', 'main subject')]
# [('property', 'http://www.wikidata.org/prop/direct/P144'), ('propertyName', 'based on')]
# [('property', 'http://www.wikidata.org/prop/direct/P155'), ('propertyName', 'follows')]
# [('property', 'http://www.wikidata.org/prop/direct/P179'), ('propertyName', 'part of the series')]
# [('property', 'http://www.wikidata.org/prop/direct/P123'), ('propertyName', 'publisher')]
# [('property', 'http://www.wikidata.org/prop/direct/P737'), ('propertyName', 'influenced by')]
# [('property', 'http://www.wikidata.org/prop/direct/P9883'), ('propertyName', 'created for')]
# [('property', 'http://www.wikidata.org/prop/direct/P941'), ('propertyName', 'inspired by')]
# [('property', 'http://www.wikidata.org/prop/direct/P361'), ('propertyName', 'part of')]
# 12

# %%
#Return all properties connecting "film" objects to "Written works" objects
queryString = """
SELECT DISTINCT ?property ?propertyName
WHERE {
    
    # ?writtenWork wdt:P31 wd:Q47461344.
    # ?film wdt:P31 wd:Q11424.
    
    # ?film ?property ?writtenWork.
    # ?property <http://schema.org/name> ?propertyName.
    
}

"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('property', 'http://www.wikidata.org/prop/direct/P144'), ('propertyName', 'based on')]
# [('property', 'http://www.wikidata.org/prop/direct/P1889'), ('propertyName', 'different from')]
# [('property', 'http://www.wikidata.org/prop/direct/P4969'), ('propertyName', 'derivative work')]
# [('property', 'http://www.wikidata.org/prop/direct/P941'), ('propertyName', 'inspired by')]
# [('property', 'http://www.wikidata.org/prop/direct/P5940'), ('propertyName', 'plot expanded in')]
# [('property', 'http://www.wikidata.org/prop/direct/P921'), ('propertyName', 'main subject')]
# [('property', 'http://www.wikidata.org/prop/direct/P6166'), ('propertyName', 'quotes work')]
# [('property', 'http://www.wikidata.org/prop/direct/P272'), ('propertyName', 'production company')]
# [('property', 'http://www.wikidata.org/prop/direct/P155'), ('propertyName', 'follows')]
# [('property', 'http://www.wikidata.org/prop/direct/P138'), ('propertyName', 'named after')]
# [('property', 'http://www.wikidata.org/prop/direct/P527'), ('propertyName', 'has part')]
# [('property', 'http://www.wikidata.org/prop/direct/P8371'), ('propertyName', 'references work, tradition or theory')]
# [('property', 'http://www.wikidata.org/prop/direct/P1343'), ('propertyName', 'described by source')]
# [('property', 'http://www.wikidata.org/prop/direct/P179'), ('propertyName', 'part of the series')]
# [('property', 'http://www.wikidata.org/prop/direct/P361'), ('propertyName', 'part of')]
# [('property', 'http://www.wikidata.org/prop/direct/P737'), ('propertyName', 'influenced by')]
# [('property', 'http://www.wikidata.org/prop/direct/P156'), ('propertyName', 'followed by')]
# [('property', 'http://www.wikidata.org/prop/direct/P2283'), ('propertyName', 'uses')]
# [('property', 'http://www.wikidata.org/prop/direct/P58'), ('propertyName', 'screenwriter')]
# 19

# %%
#Return all "film title" that have "derivative work", "inspired by", "based on", "influenced by" relations with a "Written work" with Paul Auster as author 
queryString = """
SELECT DISTINCT ?filmTitle ?propertyName ?bookTitle
WHERE {
    
    # ?writtenWork wdt:P31 wd:Q47461344.
    # ?writtenWork wdt:P50 wd:Q214642.
    # ?writtenWork wdt:P1476 ?bookTitle.
    
    # ?film wdt:P31 wd:Q11424.
    # ?film wdt:P1476 ?filmTitle.
    
    # ?film ?property ?writtenWork.
    # ?property <http://schema.org/name> ?propertyName.
    
    FILTER(?property = wdt:P4969 || ?property = wdt:P941 || ?property = wdt:P144 || ?property = wdt:P737)
    
}

"""

print("Results")
run_query(queryString)
# Out:
# Results
# Empty
# 0

# %%
#Return all "film title" that have "derivative work", "inspired by", "based on", "influenced by" relations with a "Written work" with Ian McEwan as author 
queryString = """
SELECT DISTINCT ?filmTitle ?propertyName ?bookTitle
WHERE {
    
    # ?writtenWork wdt:P31 wd:Q47461344.
    # ?writtenWork wdt:P50 wd:Q190379.
    # ?writtenWork wdt:P1476 ?bookTitle.
    
    # ?film wdt:P31 wd:Q11424.
    # ?film wdt:P1476 ?filmTitle.
    
    # ?film ?property ?writtenWork.
    # ?property <http://schema.org/name> ?propertyName.
    
    FILTER(?property = wdt:P4969 || ?property = wdt:P941 || ?property = wdt:P144 || ?property = wdt:P737)
    
}

"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('filmTitle', 'On Chesil Beach'), ('propertyName', 'based on'), ('bookTitle', 'On Chesil Beach')]
# [('filmTitle', 'Atonement'), ('propertyName', 'based on'), ('bookTitle', 'Atonement')]
# [('filmTitle', 'The Cement Garden'), ('propertyName', 'based on'), ('bookTitle', 'The Cement Garden')]
# 3

# %%
#How many films were derived from the books of these two authors?
queryString = """
SELECT DISTINCT ?authorName (COUNT(?film) AS ?derivedFilms)
WHERE {
    
    {
        # ?writtenWork wdt:P31 wd:Q47461344.
        # ?writtenWork wdt:P50 wd:Q214642.
        wd:Q214642 wdt:P1559 ?authorName.
    }
    UNION
    {
        # ?writtenWork wdt:P31 wd:Q47461344.
        # ?writtenWork wdt:P50 wd:Q190379.
        wd:Q190379 wdt:P1559 ?authorName.
    }
    
    # ?film wdt:P31 wd:Q11424.
    
    # ?film ?property ?writtenWork.
    
    FILTER(?property = wdt:P4969 || ?property = wdt:P941 || ?property = wdt:P144 || ?property = wdt:P737)
    
}
GROUP BY (?authorName)

"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('authorName', 'Ian McEwan'), ('derivedFilms', '3')]
# 1

# %% [markdown]
# #### Point 4 Finish
# DESCRIPTION: I started by checking the relations between “writtenWork” and “film” and vice versa. Then I kept some interesting relationships and try to find some information about “film” related to “writtenWorks” of Paul and Ian.
# Finally I counted how many films were derived from books of both authors using “derived work” wdt:P4969, “inspired by” wdtP:941, “based on” wdt:P144 and “influenced by” wdt:P737 as relationships that connects a “film” to a “writtenWork”.
#
#
# RESULT: The final result shows that were derived only 3 films exclusively from Ian’s books.

# %% [markdown]
# #### Point 5a Start

# %%
#Return all award of Paul Auster and their instance class
queryString = """
SELECT DISTINCT ?award ?awardName ?awardTypeName ?awardType
WHERE {
    
    wd:Q214642 wdt:P166 ?award.
    # ?award <http://schema.org/name> ?awardName.
    # ?award wdt:P31 ?awardType.
    # ?awardType <http://schema.org/name> ?awardTypeName.
    
}

"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('award', 'http://www.wikidata.org/entity/Q3332454'), ('awardName', 'Princess of Asturias Literary Prize'), ('awardTypeName', 'Princess of Asturias Awards'), ('awardType', 'http://www.wikidata.org/entity/Q329157')]
# [('award', 'http://www.wikidata.org/entity/Q1188661'), ('awardName', 'PEN/Faulkner Award for Fiction'), ('awardTypeName', 'literary award'), ('awardType', 'http://www.wikidata.org/entity/Q378427')]
# [('award', 'http://www.wikidata.org/entity/Q3332454'), ('awardName', 'Princess of Asturias Literary Prize'), ('awardTypeName', 'literary award'), ('awardType', 'http://www.wikidata.org/entity/Q378427')]
# [('award', 'http://www.wikidata.org/entity/Q3405076'), ('awardName', 'Prix Médicis for foreign literature'), ('awardTypeName', 'class of award'), ('awardType', 'http://www.wikidata.org/entity/Q38033430')]
# [('award', 'http://www.wikidata.org/entity/Q13452531'), ('awardName', 'Commandeur des Arts et des Lettres\u200e'), ('awardTypeName', 'grade of an order'), ('awardType', 'http://www.wikidata.org/entity/Q60754876')]
# [('award', 'http://www.wikidata.org/entity/Q52382875'), ('awardName', 'AAAS Fellow'), ('awardTypeName', 'fellowship'), ('awardType', 'http://www.wikidata.org/entity/Q20006438')]
# 6

# %%
#Return all properties of the awards of Paul Auster
queryString = """
SELECT DISTINCT ?property ?propertyName
WHERE {
    
    wd:Q214642 wdt:P166 ?award.
    # ?award ?property ?object.
    # ?property <http://schema.org/name> ?propertyName.
    
}

"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('property', 'http://www.wikidata.org/prop/direct/P3729'), ('propertyName', 'next lower rank')]
# [('property', 'http://www.wikidata.org/prop/direct/P112'), ('propertyName', 'founded by')]
# [('property', 'http://www.wikidata.org/prop/direct/P1417'), ('propertyName', 'Encyclopædia Britannica Online ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P17'), ('propertyName', 'country')]
# [('property', 'http://www.wikidata.org/prop/direct/P18'), ('propertyName', 'image')]
# [('property', 'http://www.wikidata.org/prop/direct/P1889'), ('propertyName', 'different from')]
# [('property', 'http://www.wikidata.org/prop/direct/P2671'), ('propertyName', 'Google Knowledge Graph ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P279'), ('propertyName', 'subclass of')]
# [('property', 'http://www.wikidata.org/prop/direct/P31'), ('propertyName', 'instance of')]
# [('property', 'http://www.wikidata.org/prop/direct/P361'), ('propertyName', 'part of')]
# [('property', 'http://www.wikidata.org/prop/direct/P373'), ('propertyName', 'Commons category')]
# [('property', 'http://www.wikidata.org/prop/direct/P5008'), ('propertyName', 'on focus list of Wikimedia project')]
# [('property', 'http://www.wikidata.org/prop/direct/P569'), ('propertyName', 'date of birth')]
# [('property', 'http://www.wikidata.org/prop/direct/P571'), ('propertyName', 'inception')]
# [('property', 'http://www.wikidata.org/prop/direct/P580'), ('propertyName', 'start time')]
# [('property', 'http://www.wikidata.org/prop/direct/P646'), ('propertyName', 'Freebase ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P856'), ('propertyName', 'official website')]
# [('property', 'http://www.wikidata.org/prop/direct/P859'), ('propertyName', 'sponsor')]
# [('property', 'http://www.wikidata.org/prop/direct/P910'), ('propertyName', "topic's main category")]
# [('property', 'http://www.wikidata.org/prop/direct/P1027'), ('propertyName', 'conferred by')]
# [('property', 'http://www.wikidata.org/prop/direct/P2425'), ('propertyName', 'service ribbon image')]
# [('property', 'http://www.wikidata.org/prop/direct/P2517'), ('propertyName', 'category for recipients of this award')]
# 22

# %%
#Return all award common categories of the awards won by Paul Auster
queryString = """
SELECT ?awardName ?category
WHERE {
    
    wd:Q214642 wdt:P166 ?award.
    # ?award <http://schema.org/name> ?awardName.
    # ?award wdt:P373 ?category.

}

"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('awardName', 'Commandeur des Arts et des Lettres\u200e'), ('category', 'Commanders of the French Ordre des Arts et des Lettres')]
# [('awardName', 'AAAS Fellow'), ('category', 'Fellows of the American Academy of Arts and Sciences')]
# 2

# %%
#Return all award topic's main category of the awards won by Paul Auster
queryString = """
SELECT ?awardName ?category ?catName
WHERE {
    
    wd:Q214642 wdt:P166 ?award.
    # ?award <http://schema.org/name> ?awardName.
    # ?award wdt:P910 ?category.
    # ?category <http://schema.org/name> ?catName.

}

"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('awardName', 'PEN/Faulkner Award for Fiction'), ('category', 'http://www.wikidata.org/entity/Q8708086'), ('catName', 'Category:PEN/Faulkner Foundation awards')]
# [('awardName', 'AAAS Fellow'), ('category', 'http://www.wikidata.org/entity/Q6619589'), ('catName', 'Category:Fellows of the American Academy of Arts and Sciences')]
# [('awardName', 'Commandeur des Arts et des Lettres\u200e'), ('category', 'http://www.wikidata.org/entity/Q9145202'), ('catName', 'Category:Commandeurs of the Ordre des Arts et des Lettres')]
# 3

# %%
#Return all award category for recipients of the awards won by Paul Auster
queryString = """
SELECT ?awardName ?category ?catName
WHERE {
    
    wd:Q214642 wdt:P166 ?award.
    # ?award <http://schema.org/name> ?awardName.
    # ?award wdt:P2517 ?category.
    # ?category <http://schema.org/name> ?catName.

}

"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('awardName', 'Princess of Asturias Literary Prize'), ('category', 'http://www.wikidata.org/entity/Q17337380'), ('catName', 'Category:Recipients of the Prince of Asturias Awards')]
# [('awardName', 'AAAS Fellow'), ('category', 'http://www.wikidata.org/entity/Q6619589'), ('catName', 'Category:Fellows of the American Academy of Arts and Sciences')]
# [('awardName', 'Commandeur des Arts et des Lettres\u200e'), ('category', 'http://www.wikidata.org/entity/Q9145202'), ('catName', 'Category:Commandeurs of the Ordre des Arts et des Lettres')]
# 3

# %%
#Return all award superclasses of the awards won by Paul Auster
queryString = """
SELECT ?awardName ?superclass ?superclassName
WHERE {
    
    wd:Q214642 wdt:P166 ?award.
    # ?award <http://schema.org/name> ?awardName.
    # ?award wdt:P279 ?superclass.
    # ?superclass <http://schema.org/name> ?superclassName.

}

"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('awardName', 'AAAS Fellow'), ('superclass', 'http://www.wikidata.org/entity/Q10519151'), ('superclassName', 'honorary member')]
# [('awardName', 'Prix Médicis for foreign literature'), ('superclass', 'http://www.wikidata.org/entity/Q378427'), ('superclassName', 'literary award')]
# [('awardName', 'Commandeur des Arts et des Lettres\u200e'), ('superclass', 'http://www.wikidata.org/entity/Q524980'), ('superclassName', 'commander')]
# 3

# %%
#Return all award won by Paul Auster that are subclasses of "Literary Award" class
queryString = """
SELECT DISTINCT ?awardName ?awardType 
WHERE {
    
    wd:Q214642 wdt:P166 ?award.
    # ?award <http://schema.org/name> ?awardName.
    # ?award wdt:P279 wd:Q378427.
    # ?superclassObj wdt:P31 wd:Q378427.
    wd:Q378427 <http://schema.org/name> ?awardType.

}

"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('awardName', 'Prix Médicis for foreign literature'), ('awardType', 'literary award')]
# 1

# %%
#Return properties of literary award objects
queryString = """
SELECT DISTINCT ?property ?propertyName
WHERE {
    
    wd:Q378427 ?property ?object.
    # ?property <http://schema.org/name> ?propertyName.

}

"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('property', 'http://www.wikidata.org/prop/direct/P227'), ('propertyName', 'GND ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2347'), ('propertyName', 'YSO ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P244'), ('propertyName', 'Library of Congress authority ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2581'), ('propertyName', 'BabelNet ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P268'), ('propertyName', 'Bibliothèque nationale de France ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P279'), ('propertyName', 'subclass of')]
# [('property', 'http://www.wikidata.org/prop/direct/P31'), ('propertyName', 'instance of')]
# [('property', 'http://www.wikidata.org/prop/direct/P3222'), ('propertyName', 'NE.se ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P349'), ('propertyName', 'National Diet Library ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P373'), ('propertyName', 'Commons category')]
# [('property', 'http://www.wikidata.org/prop/direct/P3916'), ('propertyName', 'UNESCO Thesaurus ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4342'), ('propertyName', 'Store norske leksikon ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4854'), ('propertyName', 'Uppslagsverket Finland ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P508'), ('propertyName', 'BNCF Thesaurus ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5198'), ('propertyName', 'ASC Leiden Thesaurus ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6293'), ('propertyName', 'YSA ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P646'), ('propertyName', 'Freebase ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7033'), ('propertyName', 'Australian Educational Vocabulary ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P8309'), ('propertyName', 'Yle topic ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P8408'), ('propertyName', 'KBpedia ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P902'), ('propertyName', 'HDS ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P910'), ('propertyName', "topic's main category")]
# 22

# %%
#Return superclass of literature award
queryString = """
SELECT DISTINCT ?superclass ?superclassName
WHERE {
    
    wd:Q378427 wdt:P279 ?superclass.
    # ?superclass <http://schema.org/name> ?superclassName.

}

"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('superclass', 'http://www.wikidata.org/entity/Q618779'), ('superclassName', 'award')]
# [('superclass', 'http://www.wikidata.org/entity/Q1656682'), ('superclassName', 'event')]
# 2

# %%
#Return all properies of objects of award class
queryString = """
SELECT DISTINCT ?property ?propertyName
WHERE {
    
    # ?award wdt:P31 wd:Q618779.
    # ?award ?property ?object.
    # ?property <http://schema.org/name> ?propertyName.

}

"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('property', 'http://www.wikidata.org/prop/direct/P3729'), ('propertyName', 'next lower rank')]
# [('property', 'http://www.wikidata.org/prop/direct/P1001'), ('propertyName', 'applies to jurisdiction')]
# [('property', 'http://www.wikidata.org/prop/direct/P101'), ('propertyName', 'field of work')]
# [('property', 'http://www.wikidata.org/prop/direct/P1114'), ('propertyName', 'quantity')]
# [('property', 'http://www.wikidata.org/prop/direct/P1269'), ('propertyName', 'facet of')]
# [('property', 'http://www.wikidata.org/prop/direct/P131'), ('propertyName', 'located in the administrative territorial entity')]
# [('property', 'http://www.wikidata.org/prop/direct/P1343'), ('propertyName', 'described by source')]
# [('property', 'http://www.wikidata.org/prop/direct/P1346'), ('propertyName', 'winner')]
# [('property', 'http://www.wikidata.org/prop/direct/P138'), ('propertyName', 'named after')]
# [('property', 'http://www.wikidata.org/prop/direct/P1424'), ('propertyName', "topic's main template")]
# [('property', 'http://www.wikidata.org/prop/direct/P1454'), ('propertyName', 'legal form')]
# [('property', 'http://www.wikidata.org/prop/direct/P154'), ('propertyName', 'logo image')]
# [('property', 'http://www.wikidata.org/prop/direct/P155'), ('propertyName', 'follows')]
# [('property', 'http://www.wikidata.org/prop/direct/P156'), ('propertyName', 'followed by')]
# [('property', 'http://www.wikidata.org/prop/direct/P159'), ('propertyName', 'headquarters location')]
# [('property', 'http://www.wikidata.org/prop/direct/P1687'), ('propertyName', 'Wikidata property')]
# [('property', 'http://www.wikidata.org/prop/direct/P17'), ('propertyName', 'country')]
# [('property', 'http://www.wikidata.org/prop/direct/P170'), ('propertyName', 'creator')]
# [('property', 'http://www.wikidata.org/prop/direct/P1705'), ('propertyName', 'native label')]
# [('property', 'http://www.wikidata.org/prop/direct/P18'), ('propertyName', 'image')]
# [('property', 'http://www.wikidata.org/prop/direct/P1889'), ('propertyName', 'different from')]
# [('property', 'http://www.wikidata.org/prop/direct/P2001'), ('propertyName', 'Revised Romanization')]
# [('property', 'http://www.wikidata.org/prop/direct/P2002'), ('propertyName', 'Twitter username')]
# [('property', 'http://www.wikidata.org/prop/direct/P2013'), ('propertyName', 'Facebook ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2121'), ('propertyName', 'prize money')]
# [('property', 'http://www.wikidata.org/prop/direct/P214'), ('propertyName', 'VIAF ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2257'), ('propertyName', 'event interval')]
# [('property', 'http://www.wikidata.org/prop/direct/P227'), ('propertyName', 'GND ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2354'), ('propertyName', 'has list')]
# [('property', 'http://www.wikidata.org/prop/direct/P244'), ('propertyName', 'Library of Congress authority ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2581'), ('propertyName', 'BabelNet ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2671'), ('propertyName', 'Google Knowledge Graph ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P276'), ('propertyName', 'location')]
# [('property', 'http://www.wikidata.org/prop/direct/P279'), ('propertyName', 'subclass of')]
# [('property', 'http://www.wikidata.org/prop/direct/P2910'), ('propertyName', 'icon')]
# [('property', 'http://www.wikidata.org/prop/direct/P31'), ('propertyName', 'instance of')]
# [('property', 'http://www.wikidata.org/prop/direct/P361'), ('propertyName', 'part of')]
# [('property', 'http://www.wikidata.org/prop/direct/P373'), ('propertyName', 'Commons category')]
# [('property', 'http://www.wikidata.org/prop/direct/P407'), ('propertyName', 'language of work or name')]
# [('property', 'http://www.wikidata.org/prop/direct/P4342'), ('propertyName', 'Store norske leksikon ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4854'), ('propertyName', 'Uppslagsverket Finland ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P495'), ('propertyName', 'country of origin')]
# [('property', 'http://www.wikidata.org/prop/direct/P5008'), ('propertyName', 'on focus list of Wikimedia project')]
# [('property', 'http://www.wikidata.org/prop/direct/P527'), ('propertyName', 'has part')]
# [('property', 'http://www.wikidata.org/prop/direct/P5357'), ('propertyName', 'The Encyclopedia of Science Fiction ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5395'), ('propertyName', 'Canadian Encyclopedia article ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P571'), ('propertyName', 'inception')]
# [('property', 'http://www.wikidata.org/prop/direct/P576'), ('propertyName', 'dissolved, abolished or demolished date')]
# [('property', 'http://www.wikidata.org/prop/direct/P580'), ('propertyName', 'start time')]
# [('property', 'http://www.wikidata.org/prop/direct/P641'), ('propertyName', 'sport')]
# [('property', 'http://www.wikidata.org/prop/direct/P646'), ('propertyName', 'Freebase ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7305'), ('propertyName', 'Online PWN Encyclopedia ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7859'), ('propertyName', 'WorldCat Identities ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P8408'), ('propertyName', 'KBpedia ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P856'), ('propertyName', 'official website')]
# [('property', 'http://www.wikidata.org/prop/direct/P859'), ('propertyName', 'sponsor')]
# [('property', 'http://www.wikidata.org/prop/direct/P8687'), ('propertyName', 'social media followers')]
# [('property', 'http://www.wikidata.org/prop/direct/P910'), ('propertyName', "topic's main category")]
# [('property', 'http://www.wikidata.org/prop/direct/P921'), ('propertyName', 'main subject')]
# [('property', 'http://www.wikidata.org/prop/direct/P968'), ('propertyName', 'email address')]
# [('property', 'http://www.wikidata.org/prop/direct/P167'), ('propertyName', 'structure replaced by')]
# [('property', 'http://www.wikidata.org/prop/direct/P1027'), ('propertyName', 'conferred by')]
# [('property', 'http://www.wikidata.org/prop/direct/P2425'), ('propertyName', 'service ribbon image')]
# [('property', 'http://www.wikidata.org/prop/direct/P2517'), ('propertyName', 'category for recipients of this award')]
# [('property', 'http://www.wikidata.org/prop/direct/P2669'), ('propertyName', 'discontinued date')]
# [('property', 'http://www.wikidata.org/prop/direct/P3730'), ('propertyName', 'next higher rank')]
# [('property', 'http://www.wikidata.org/prop/direct/P2378'), ('propertyName', 'issued by')]
# [('property', 'http://www.wikidata.org/prop/direct/P1028'), ('propertyName', 'donated by')]
# [('property', 'http://www.wikidata.org/prop/direct/P4003'), ('propertyName', 'Facebook page ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P9486'), ('propertyName', 'HERO ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P112'), ('propertyName', 'founded by')]
# [('property', 'http://www.wikidata.org/prop/direct/P137'), ('propertyName', 'operator')]
# [('property', 'http://www.wikidata.org/prop/direct/P1417'), ('propertyName', 'Encyclopædia Britannica Online ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P176'), ('propertyName', 'manufacturer')]
# [('property', 'http://www.wikidata.org/prop/direct/P1813'), ('propertyName', 'short name')]
# [('property', 'http://www.wikidata.org/prop/direct/P1814'), ('propertyName', 'name in kana')]
# [('property', 'http://www.wikidata.org/prop/direct/P186'), ('propertyName', 'made from material')]
# [('property', 'http://www.wikidata.org/prop/direct/P1963'), ('propertyName', 'properties for this type')]
# [('property', 'http://www.wikidata.org/prop/direct/P2003'), ('propertyName', 'Instagram username')]
# [('property', 'http://www.wikidata.org/prop/direct/P2067'), ('propertyName', 'mass')]
# [('property', 'http://www.wikidata.org/prop/direct/P213'), ('propertyName', 'ISNI')]
# [('property', 'http://www.wikidata.org/prop/direct/P2386'), ('propertyName', 'diameter')]
# [('property', 'http://www.wikidata.org/prop/direct/P2427'), ('propertyName', 'GRID ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2541'), ('propertyName', 'operating area')]
# [('property', 'http://www.wikidata.org/prop/direct/P2572'), ('propertyName', 'hashtag')]
# [('property', 'http://www.wikidata.org/prop/direct/P268'), ('propertyName', 'Bibliothèque nationale de France ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P269'), ('propertyName', 'IdRef ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P287'), ('propertyName', 'designed by')]
# [('property', 'http://www.wikidata.org/prop/direct/P2896'), ('propertyName', 'publication interval')]
# [('property', 'http://www.wikidata.org/prop/direct/P2922'), ('propertyName', 'month of the year')]
# [('property', 'http://www.wikidata.org/prop/direct/P3095'), ('propertyName', 'practiced by')]
# [('property', 'http://www.wikidata.org/prop/direct/P3301'), ('propertyName', 'broadcast by')]
# [('property', 'http://www.wikidata.org/prop/direct/P3417'), ('propertyName', 'Quora topic ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4013'), ('propertyName', 'Giphy username')]
# [('property', 'http://www.wikidata.org/prop/direct/P444'), ('propertyName', 'review score')]
# [('property', 'http://www.wikidata.org/prop/direct/P460'), ('propertyName', 'said to be the same as')]
# [('property', 'http://www.wikidata.org/prop/direct/P4622'), ('propertyName', 'trophy awarded')]
# [('property', 'http://www.wikidata.org/prop/direct/P4839'), ('propertyName', 'Wolfram Language entity code')]
# [('property', 'http://www.wikidata.org/prop/direct/P582'), ('propertyName', 'end time')]
# [('property', 'http://www.wikidata.org/prop/direct/P585'), ('propertyName', 'point in time')]
# [('property', 'http://www.wikidata.org/prop/direct/P664'), ('propertyName', 'organizer')]
# [('property', 'http://www.wikidata.org/prop/direct/P6782'), ('propertyName', 'ROR ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7084'), ('propertyName', 'related category')]
# [('property', 'http://www.wikidata.org/prop/direct/P710'), ('propertyName', 'participant')]
# [('property', 'http://www.wikidata.org/prop/direct/P749'), ('propertyName', 'parent organization')]
# [('property', 'http://www.wikidata.org/prop/direct/P7818'), ('propertyName', 'French Vikidia ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P793'), ('propertyName', 'significant event')]
# [('property', 'http://www.wikidata.org/prop/direct/P973'), ('propertyName', 'described at URL')]
# [('property', 'http://www.wikidata.org/prop/direct/P3579'), ('propertyName', 'Sina Weibo user ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P8742'), ('propertyName', 'PIM award ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P8629'), ('propertyName', 'Occupational Outlook Handbook ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P952'), ('propertyName', 'ISCO-88 occupation code')]
# [('property', 'http://www.wikidata.org/prop/direct/P8734'), ('propertyName', 'O*NET OnLine code')]
# [('property', 'http://www.wikidata.org/prop/direct/P4015'), ('propertyName', 'Vimeo identifier')]
# [('property', 'http://www.wikidata.org/prop/direct/P1017'), ('propertyName', 'Vatican Library ID (former scheme)')]
# [('property', 'http://www.wikidata.org/prop/direct/P136'), ('propertyName', 'genre')]
# [('property', 'http://www.wikidata.org/prop/direct/P1365'), ('propertyName', 'replaces')]
# [('property', 'http://www.wikidata.org/prop/direct/P1366'), ('propertyName', 'replaced by')]
# [('property', 'http://www.wikidata.org/prop/direct/P1438'), ('propertyName', 'Jewish Encyclopedia ID (Russian)')]
# [('property', 'http://www.wikidata.org/prop/direct/P180'), ('propertyName', 'depicts')]
# [('property', 'http://www.wikidata.org/prop/direct/P2397'), ('propertyName', 'YouTube channel ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2561'), ('propertyName', 'name')]
# [('property', 'http://www.wikidata.org/prop/direct/P2603'), ('propertyName', 'Kinopoisk film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2924'), ('propertyName', 'Great Russian Encyclopedia Online ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3221'), ('propertyName', 'New York Times topic ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P345'), ('propertyName', 'IMDb ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P360'), ('propertyName', 'is a list of')]
# [('property', 'http://www.wikidata.org/prop/direct/P452'), ('propertyName', 'industry')]
# [('property', 'http://www.wikidata.org/prop/direct/P547'), ('propertyName', 'commemorates')]
# [('property', 'http://www.wikidata.org/prop/direct/P607'), ('propertyName', 'conflict')]
# [('property', 'http://www.wikidata.org/prop/direct/P6366'), ('propertyName', 'Microsoft Academic ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6839'), ('propertyName', 'TV Tropes identifier')]
# [('property', 'http://www.wikidata.org/prop/direct/P691'), ('propertyName', 'NKCR AUT ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7012'), ('propertyName', 'World Encyclopedia of Puppetry Arts ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P8034'), ('propertyName', 'Vatican Library VcBA ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P8432'), ('propertyName', 'Österreichisches Musiklexikon Online ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P8796'), ('propertyName', 'FilmPolski press collection ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P9226'), ('propertyName', 'ARAE ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P935'), ('propertyName', 'Commons gallery')]
# [('property', 'http://www.wikidata.org/prop/direct/P948'), ('propertyName', 'page banner')]
# [('property', 'http://www.wikidata.org/prop/direct/P950'), ('propertyName', 'Biblioteca Nacional de España ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3943'), ('propertyName', 'Tumblr username')]
# [('property', 'http://www.wikidata.org/prop/direct/P4903'), ('propertyName', 'New Georgia Encyclopedia ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P748'), ('propertyName', 'appointed by')]
# [('property', 'http://www.wikidata.org/prop/direct/P1686'), ('propertyName', 'for work')]
# [('property', 'http://www.wikidata.org/prop/direct/P854'), ('propertyName', 'reference URL')]
# [('property', 'http://www.wikidata.org/prop/direct/P1051'), ('propertyName', 'PSH ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1151'), ('propertyName', "topic's main Wikimedia portal")]
# [('property', 'http://www.wikidata.org/prop/direct/P1225'), ('propertyName', 'U.S. National Archives Identifier')]
# [('property', 'http://www.wikidata.org/prop/direct/P1245'), ('propertyName', 'OmegaWiki Defined Meaning')]
# [('property', 'http://www.wikidata.org/prop/direct/P1296'), ('propertyName', 'Gran Enciclopèdia Catalana ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1617'), ('propertyName', 'BBC Things ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P166'), ('propertyName', 'award received')]
# [('property', 'http://www.wikidata.org/prop/direct/P1709'), ('propertyName', 'equivalent class')]
# [('property', 'http://www.wikidata.org/prop/direct/P2347'), ('propertyName', 'YSO ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2738'), ('propertyName', 'disjoint union of')]
# [('property', 'http://www.wikidata.org/prop/direct/P282'), ('propertyName', 'writing system')]
# [('property', 'http://www.wikidata.org/prop/direct/P2959'), ('propertyName', 'permanent duplicated item')]
# [('property', 'http://www.wikidata.org/prop/direct/P3106'), ('propertyName', 'Guardian topic ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3222'), ('propertyName', 'NE.se ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P349'), ('propertyName', 'National Diet Library ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3509'), ('propertyName', 'Dagens Nyheter topic ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3553'), ('propertyName', 'Zhihu topic ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3630'), ('propertyName', 'Babelio author ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3911'), ('propertyName', 'STW Thesaurus for Economics ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4431'), ('propertyName', 'Google Doodle')]
# [('property', 'http://www.wikidata.org/prop/direct/P4527'), ('propertyName', 'UK Parliament thesaurus ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P486'), ('propertyName', 'MeSH descriptor ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P508'), ('propertyName', 'BNCF Thesaurus ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5905'), ('propertyName', 'Comic Vine ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6016'), ('propertyName', 'Tennessee Encyclopedia ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6081'), ('propertyName', 'RIA Novosti reference')]
# [('property', 'http://www.wikidata.org/prop/direct/P6200'), ('propertyName', 'BBC News topic ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6228'), ('propertyName', 'RegiowikiAT ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6293'), ('propertyName', 'YSA ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6520'), ('propertyName', 'Lokalhistoriewiki.no ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6573'), ('propertyName', 'Klexikon article ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6817'), ('propertyName', 'SVT Play ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6849'), ('propertyName', 'DR topic ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7502'), ('propertyName', 'Golden ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P8309'), ('propertyName', 'Yle topic ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P837'), ('propertyName', 'day in year for periodic occurrence')]
# [('property', 'http://www.wikidata.org/prop/direct/P898'), ('propertyName', 'IPA transcription')]
# [('property', 'http://www.wikidata.org/prop/direct/P9100'), ('propertyName', 'GitHub topic')]
# [('property', 'http://www.wikidata.org/prop/direct/P9318'), ('propertyName', 'Ávvir topic ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P9545'), ('propertyName', 'Encyclopedia of China Online Database ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P989'), ('propertyName', 'spoken text audio')]
# [('property', 'http://www.wikidata.org/prop/direct/P8115'), ('propertyName', 'eligible recipient')]
# [('property', 'http://www.wikidata.org/prop/direct/P1014'), ('propertyName', 'Art & Architecture Thesaurus ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P126'), ('propertyName', 'maintained by')]
# [('property', 'http://www.wikidata.org/prop/direct/P140'), ('propertyName', 'religion')]
# [('property', 'http://www.wikidata.org/prop/direct/P1416'), ('propertyName', 'affiliation')]
# [('property', 'http://www.wikidata.org/prop/direct/P1448'), ('propertyName', 'official name')]
# [('property', 'http://www.wikidata.org/prop/direct/P2670'), ('propertyName', 'has parts of the class')]
# [('property', 'http://www.wikidata.org/prop/direct/P272'), ('propertyName', 'production company')]
# [('property', 'http://www.wikidata.org/prop/direct/P2847'), ('propertyName', 'Google+ ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P30'), ('propertyName', 'continent')]
# [('property', 'http://www.wikidata.org/prop/direct/P301'), ('propertyName', "category's main topic")]
# [('property', 'http://www.wikidata.org/prop/direct/P4212'), ('propertyName', 'PACTOLS thesaurus ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6104'), ('propertyName', 'maintained by WikiProject')]
# [('property', 'http://www.wikidata.org/prop/direct/P6262'), ('propertyName', 'Fandom article ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6404'), ('propertyName', "Treccani's Dizionario di Storia ID")]
# [('property', 'http://www.wikidata.org/prop/direct/P6900'), ('propertyName', 'NicoNicoPedia ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P797'), ('propertyName', 'authority')]
# [('property', 'http://www.wikidata.org/prop/direct/P8519'), ('propertyName', 'RKD thesaurus ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P9000'), ('propertyName', 'World History Encyclopedia ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1536'), ('propertyName', 'immediate cause of')]
# [('property', 'http://www.wikidata.org/prop/direct/P1407'), ('propertyName', 'MusicBrainz series ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1476'), ('propertyName', 'title')]
# [('property', 'http://www.wikidata.org/prop/direct/P2094'), ('propertyName', 'competition class')]
# [('property', 'http://www.wikidata.org/prop/direct/P2284'), ('propertyName', 'price')]
# [('property', 'http://www.wikidata.org/prop/direct/P449'), ('propertyName', 'original broadcaster')]
# [('property', 'http://www.wikidata.org/prop/direct/P8514'), ('propertyName', 'TOPCMB ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5300'), ('propertyName', 'Webb-site organization ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6277'), ('propertyName', 'Objectif Gard topic ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7437'), ('propertyName', 'FantLab award ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P106'), ('propertyName', 'occupation')]
# [('property', 'http://www.wikidata.org/prop/direct/P3219'), ('propertyName', 'Encyclopædia Universalis ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3500'), ('propertyName', 'Ringgold ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P364'), ('propertyName', 'original language of film or TV show')]
# [('property', 'http://www.wikidata.org/prop/direct/P457'), ('propertyName', 'foundational text')]
# [('property', 'http://www.wikidata.org/prop/direct/P577'), ('propertyName', 'publication date')]
# [('property', 'http://www.wikidata.org/prop/direct/P6181'), ('propertyName', 'Disney A to Z ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P8974'), ('propertyName', 'SAPA ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P98'), ('propertyName', 'editor')]
# [('property', 'http://www.wikidata.org/prop/direct/P1611'), ('propertyName', 'NATO code for grade')]
# [('property', 'http://www.wikidata.org/prop/direct/P7927'), ('propertyName', 'Open Food Facts label')]
# [('property', 'http://www.wikidata.org/prop/direct/P8766'), ('propertyName', 'rank insignia')]
# [('property', 'http://www.wikidata.org/prop/direct/P2699'), ('propertyName', 'URL')]
# [('property', 'http://www.wikidata.org/prop/direct/P1036'), ('propertyName', 'Dewey Decimal Classification')]
# [('property', 'http://www.wikidata.org/prop/direct/P1113'), ('propertyName', 'number of episodes')]
# [('property', 'http://www.wikidata.org/prop/direct/P1256'), ('propertyName', 'Iconclass notation')]
# [('property', 'http://www.wikidata.org/prop/direct/P1451'), ('propertyName', 'motto text')]
# [('property', 'http://www.wikidata.org/prop/direct/P1566'), ('propertyName', 'GeoNames ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1753'), ('propertyName', 'list related to category')]
# [('property', 'http://www.wikidata.org/prop/direct/P3185'), ('propertyName', 'VK ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P366'), ('propertyName', 'use')]
# [('property', 'http://www.wikidata.org/prop/direct/P5002'), ('propertyName', 'Orthodox Encyclopedia ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5019'), ('propertyName', 'Brockhaus Enzyklopädie online ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5327'), ('propertyName', 'fernsehserien.de ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7140'), ('propertyName', 'München Wiki article ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P8814'), ('propertyName', 'WordNet 3.1 Synset ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2559'), ('propertyName', 'Wikidata usage instructions')]
# [('property', 'http://www.wikidata.org/prop/direct/P4004'), ('propertyName', 'escutcheon image')]
# [('property', 'http://www.wikidata.org/prop/direct/P8295'), ('propertyName', 'AustLit ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1419'), ('propertyName', 'shape')]
# [('property', 'http://www.wikidata.org/prop/direct/P1712'), ('propertyName', 'Metacritic ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1741'), ('propertyName', 'GTAA ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3794'), ('propertyName', 'Dictionary of Sydney ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P69'), ('propertyName', 'educated at')]
# [('property', 'http://www.wikidata.org/prop/direct/P740'), ('propertyName', 'location of formation')]
# [('property', 'http://www.wikidata.org/prop/direct/P945'), ('propertyName', 'allegiance')]
# [('property', 'http://www.wikidata.org/prop/direct/P1308'), ('propertyName', 'officeholder')]
# [('property', 'http://www.wikidata.org/prop/direct/P7417'), ('propertyName', 'image of backside')]
# [('property', 'http://www.wikidata.org/prop/direct/P10'), ('propertyName', 'video')]
# [('property', 'http://www.wikidata.org/prop/direct/P1754'), ('propertyName', 'category related to list')]
# [('property', 'http://www.wikidata.org/prop/direct/P195'), ('propertyName', 'collection')]
# [('property', 'http://www.wikidata.org/prop/direct/P2650'), ('propertyName', 'interested in')]
# [('property', 'http://www.wikidata.org/prop/direct/P443'), ('propertyName', 'pronunciation audio')]
# [('property', 'http://www.wikidata.org/prop/direct/P6713'), ('propertyName', 'Australian War Memorial ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P825'), ('propertyName', 'dedicated to')]
# [('property', 'http://www.wikidata.org/prop/direct/P7418'), ('propertyName', 'image of frontside')]
# [('property', 'http://www.wikidata.org/prop/direct/P6006'), ('propertyName', 'Museum Universe Data File ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4967'), ('propertyName', 'prerequisite')]
# [('property', 'http://www.wikidata.org/prop/direct/P1004'), ('propertyName', 'MusicBrainz place ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1005'), ('propertyName', 'Portuguese National Library ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1015'), ('propertyName', 'NORAF ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1019'), ('propertyName', 'web feed URL')]
# [('property', 'http://www.wikidata.org/prop/direct/P1315'), ('propertyName', 'NLA Trove ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1612'), ('propertyName', 'Commons Institution page')]
# [('property', 'http://www.wikidata.org/prop/direct/P2011'), ('propertyName', 'Cooper-Hewitt Person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P245'), ('propertyName', 'Union List of Artist Names ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3360'), ('propertyName', 'Nobel Prize People Nomination ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3987'), ('propertyName', 'SHARE Catalogue author ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P409'), ('propertyName', 'Libraries Australia ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6365'), ('propertyName', 'member category')]
# [('property', 'http://www.wikidata.org/prop/direct/P7704'), ('propertyName', 'Europeana entity')]
# [('property', 'http://www.wikidata.org/prop/direct/P8324'), ('propertyName', 'funder')]
# [('property', 'http://www.wikidata.org/prop/direct/P3642'), ('propertyName', 'ARCHON code')]
# [('property', 'http://www.wikidata.org/prop/direct/P2667'), ('propertyName', 'corresponding template')]
# [('property', 'http://www.wikidata.org/prop/direct/P4444'), ('propertyName', 'reward')]
# [('property', 'http://www.wikidata.org/prop/direct/P127'), ('propertyName', 'owned by')]
# [('property', 'http://www.wikidata.org/prop/direct/P135'), ('propertyName', 'movement')]
# [('property', 'http://www.wikidata.org/prop/direct/P2348'), ('propertyName', 'time period')]
# [('property', 'http://www.wikidata.org/prop/direct/P828'), ('propertyName', 'has cause')]
# [('property', 'http://www.wikidata.org/prop/direct/P8672'), ('propertyName', 'Twitter topic ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1891'), ('propertyName', 'signatory')]
# [('property', 'http://www.wikidata.org/prop/direct/P281'), ('propertyName', 'postal code')]
# [('property', 'http://www.wikidata.org/prop/direct/P485'), ('propertyName', 'archives at')]
# [('property', 'http://www.wikidata.org/prop/direct/P6375'), ('propertyName', 'street address')]
# [('property', 'http://www.wikidata.org/prop/direct/P4186'), ('propertyName', "Australian Women's Register ID")]
# [('property', 'http://www.wikidata.org/prop/direct/P2918'), ('propertyName', 'PO Box')]
# [('property', 'http://www.wikidata.org/prop/direct/P7817'), ('propertyName', 'Electronic library Ukrainica ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1132'), ('propertyName', 'number of participants')]
# [('property', 'http://www.wikidata.org/prop/direct/P179'), ('propertyName', 'part of the series')]
# [('property', 'http://www.wikidata.org/prop/direct/P3569'), ('propertyName', 'Cultureel Woordenboek ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P393'), ('propertyName', 'edition number')]
# [('property', 'http://www.wikidata.org/prop/direct/P461'), ('propertyName', 'opposite of')]
# [('property', 'http://www.wikidata.org/prop/direct/P4613'), ('propertyName', 'Encyclopedia of Modern Ukraine ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P488'), ('propertyName', 'chairperson')]
# [('property', 'http://www.wikidata.org/prop/direct/P1299'), ('propertyName', 'depicted by')]
# [('property', 'http://www.wikidata.org/prop/direct/P27'), ('propertyName', 'country of citizenship')]
# [('property', 'http://www.wikidata.org/prop/direct/P3241'), ('propertyName', 'Catholic Encyclopedia ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3827'), ('propertyName', 'JSTOR topic ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6683'), ('propertyName', 'Alexander Turnbull Library ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P19'), ('propertyName', 'place of birth')]
# [('property', 'http://www.wikidata.org/prop/direct/P8144'), ('propertyName', 'Ternopil Encyclopedia ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2389'), ('propertyName', 'organization directed by the office or position')]
# [('property', 'http://www.wikidata.org/prop/direct/P1104'), ('propertyName', 'number of pages')]
# [('property', 'http://www.wikidata.org/prop/direct/P118'), ('propertyName', 'league')]
# [('property', 'http://www.wikidata.org/prop/direct/P2579'), ('propertyName', 'studied by')]
# [('property', 'http://www.wikidata.org/prop/direct/P2942'), ('propertyName', 'Dailymotion channel ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3836'), ('propertyName', 'Pinterest username')]
# [('property', 'http://www.wikidata.org/prop/direct/P50'), ('propertyName', 'author')]
# [('property', 'http://www.wikidata.org/prop/direct/P5331'), ('propertyName', 'OCLC work ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P553'), ('propertyName', 'website account on')]
# [('property', 'http://www.wikidata.org/prop/direct/P5769'), ('propertyName', 'editor-in-chief')]
# [('property', 'http://www.wikidata.org/prop/direct/P6947'), ('propertyName', 'Goodreads series ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7085'), ('propertyName', 'TikTok username')]
# [('property', 'http://www.wikidata.org/prop/direct/P8383'), ('propertyName', 'Goodreads work ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P9307'), ('propertyName', 'Fancyclopedia 3 ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P953'), ('propertyName', 'full work available at URL')]
# [('property', 'http://www.wikidata.org/prop/direct/P2984'), ('propertyName', 'Snapchat username')]
# [('property', 'http://www.wikidata.org/prop/direct/P3035'), ('propertyName', 'ISBN publisher prefix')]
# [('property', 'http://www.wikidata.org/prop/direct/P1552'), ('propertyName', 'has quality')]
# [('property', 'http://www.wikidata.org/prop/direct/P162'), ('propertyName', 'producer')]
# [('property', 'http://www.wikidata.org/prop/direct/P3280'), ('propertyName', 'BAnQ author ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P37'), ('propertyName', 'official language')]
# [('property', 'http://www.wikidata.org/prop/direct/P966'), ('propertyName', 'MusicBrainz label ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1326'), ('propertyName', 'latest date')]
# [('property', 'http://www.wikidata.org/prop/direct/P1801'), ('propertyName', 'commemorative plaque image')]
# [('property', 'http://www.wikidata.org/prop/direct/P2048'), ('propertyName', 'height')]
# [('property', 'http://www.wikidata.org/prop/direct/P2049'), ('propertyName', 'width')]
# [('property', 'http://www.wikidata.org/prop/direct/P2283'), ('propertyName', 'uses')]
# [('property', 'http://www.wikidata.org/prop/direct/P2612'), ('propertyName', 'TED topic ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P425'), ('propertyName', 'field of this occupation')]
# [('property', 'http://www.wikidata.org/prop/direct/P5058'), ('propertyName', 'Encyklopedia Teatru Polskiego person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1320'), ('propertyName', 'OpenCorporates ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1545'), ('propertyName', 'series ordinal')]
# [('property', 'http://www.wikidata.org/prop/direct/P2357'), ('propertyName', 'Classification of Instructional Programs code')]
# [('property', 'http://www.wikidata.org/prop/direct/P243'), ('propertyName', 'OCLC control number')]
# [('property', 'http://www.wikidata.org/prop/direct/P2437'), ('propertyName', 'number of seasons')]
# [('property', 'http://www.wikidata.org/prop/direct/P1923'), ('propertyName', 'participating team')]
# [('property', 'http://www.wikidata.org/prop/direct/P212'), ('propertyName', 'ISBN-13')]
# [('property', 'http://www.wikidata.org/prop/direct/P957'), ('propertyName', 'ISBN-10')]
# [('property', 'http://www.wikidata.org/prop/direct/P2333'), ('propertyName', 'Norwegian organisation number')]
# [('property', 'http://www.wikidata.org/prop/direct/P3450'), ('propertyName', 'sports season of league or competition')]
# [('property', 'http://www.wikidata.org/prop/direct/P1056'), ('propertyName', 'product or material produced')]
# [('property', 'http://www.wikidata.org/prop/direct/P2088'), ('propertyName', 'Crunchbase organization ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2360'), ('propertyName', 'intended public')]
# [('property', 'http://www.wikidata.org/prop/direct/P2124'), ('propertyName', 'member count')]
# [('property', 'http://www.wikidata.org/prop/direct/P3320'), ('propertyName', 'board member')]
# [('property', 'http://www.wikidata.org/prop/direct/P371'), ('propertyName', 'presenter')]
# [('property', 'http://www.wikidata.org/prop/direct/P4794'), ('propertyName', 'season starts')]
# [('property', 'http://www.wikidata.org/prop/direct/P2652'), ('propertyName', 'partnership with')]
# [('property', 'http://www.wikidata.org/prop/direct/P4135'), ('propertyName', 'maximum age')]
# [('property', 'http://www.wikidata.org/prop/direct/P2899'), ('propertyName', 'minimum age')]
# [('property', 'http://www.wikidata.org/prop/direct/P1619'), ('propertyName', 'date of official opening')]
# [('property', 'http://www.wikidata.org/prop/direct/P747'), ('propertyName', 'has edition or translation')]
# [('property', 'http://www.wikidata.org/prop/direct/P7153'), ('propertyName', 'significant place')]
# [('property', 'http://www.wikidata.org/prop/direct/P7076'), ('propertyName', 'Zaragoza public art ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1684'), ('propertyName', 'inscription')]
# [('property', 'http://www.wikidata.org/prop/direct/P6208'), ('propertyName', 'award rationale')]
# [('property', 'http://www.wikidata.org/prop/direct/P1264'), ('propertyName', 'valid in period')]
# [('property', 'http://www.wikidata.org/prop/direct/P2416'), ('propertyName', 'sports discipline competed in')]
# [('property', 'http://www.wikidata.org/prop/direct/P462'), ('propertyName', 'color')]
# [('property', 'http://www.wikidata.org/prop/direct/P7772'), ('propertyName', 'Atlas Obscura identifier')]
# [('property', 'http://www.wikidata.org/prop/direct/P8350'), ('propertyName', 'Singapore Infopedia ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1942'), ('propertyName', 'McCune-Reischauer romanization')]
# [('property', 'http://www.wikidata.org/prop/direct/P3984'), ('propertyName', 'subreddit')]
# [('property', 'http://www.wikidata.org/prop/direct/P2453'), ('propertyName', 'nominee')]
# [('property', 'http://www.wikidata.org/prop/direct/P123'), ('propertyName', 'publisher')]
# [('property', 'http://www.wikidata.org/prop/direct/P1412'), ('propertyName', 'languages spoken, written or signed')]
# [('property', 'http://www.wikidata.org/prop/direct/P4224'), ('propertyName', 'category contains')]
# [('property', 'http://www.wikidata.org/prop/direct/P827'), ('propertyName', 'BBC programme ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P92'), ('propertyName', 'main regulatory text')]
# [('property', 'http://www.wikidata.org/prop/direct/P1174'), ('propertyName', 'visitors per year')]
# [('property', 'http://www.wikidata.org/prop/direct/P6155'), ('propertyName', "Sotheby's Museum Network ID")]
# [('property', 'http://www.wikidata.org/prop/direct/P21'), ('propertyName', 'sex or gender')]
# [('property', 'http://www.wikidata.org/prop/direct/P3365'), ('propertyName', 'Treccani ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P355'), ('propertyName', 'subsidiary')]
# [('property', 'http://www.wikidata.org/prop/direct/P569'), ('propertyName', 'date of birth')]
# [('property', 'http://www.wikidata.org/prop/direct/P971'), ('propertyName', 'category combines topics')]
# [('property', 'http://www.wikidata.org/prop/direct/P1191'), ('propertyName', 'date of first performance')]
# [('property', 'http://www.wikidata.org/prop/direct/P3479'), ('propertyName', 'Omni topic ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5247'), ('propertyName', 'Giant Bomb ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P642'), ('propertyName', 'of')]
# [('property', 'http://www.wikidata.org/prop/direct/P463'), ('propertyName', 'member of')]
# [('property', 'http://www.wikidata.org/prop/direct/P88'), ('propertyName', 'commissioned by')]
# [('property', 'http://www.wikidata.org/prop/direct/P7033'), ('propertyName', 'Australian Educational Vocabulary ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P9035'), ('propertyName', 'Muck Rack media outlet ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P941'), ('propertyName', 'inspired by')]
# [('property', 'http://www.wikidata.org/prop/direct/P9322'), ('propertyName', 'SVKKL authority ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P518'), ('propertyName', 'applies to part')]
# [('property', 'http://www.wikidata.org/prop/direct/P2139'), ('propertyName', 'total revenue')]
# [('property', 'http://www.wikidata.org/prop/direct/P1297'), ('propertyName', 'IRS Employer Identification Number')]
# [('property', 'http://www.wikidata.org/prop/direct/P4861'), ('propertyName', 'Charity Navigator ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1651'), ('propertyName', 'YouTube video ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P217'), ('propertyName', 'inventory number')]
# [('property', 'http://www.wikidata.org/prop/direct/P2610'), ('propertyName', 'thickness')]
# [('property', 'http://www.wikidata.org/prop/direct/P1212'), ('propertyName', 'Atlas ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P9394'), ('propertyName', 'Louvre Museum ARK ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P8030'), ('propertyName', 'size designation')]
# [('property', 'http://www.wikidata.org/prop/direct/P1368'), ('propertyName', 'LNB ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2031'), ('propertyName', 'work period (start)')]
# [('property', 'http://www.wikidata.org/prop/direct/P2032'), ('propertyName', 'work period (end)')]
# [('property', 'http://www.wikidata.org/prop/direct/P2042'), ('propertyName', 'Artsy artist ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P241'), ('propertyName', 'military branch')]
# [('property', 'http://www.wikidata.org/prop/direct/P3153'), ('propertyName', 'Crossref funder ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3342'), ('propertyName', 'significant person')]
# [('property', 'http://www.wikidata.org/prop/direct/P7293'), ('propertyName', 'PLWABN ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1044'), ('propertyName', 'SWB editions')]
# [('property', 'http://www.wikidata.org/prop/direct/P1594'), ('propertyName', 'judge')]
# [('property', 'http://www.wikidata.org/prop/direct/P6802'), ('propertyName', 'related image')]
# [('property', 'http://www.wikidata.org/prop/direct/P2975'), ('propertyName', 'host')]
# [('property', 'http://www.wikidata.org/prop/direct/P9122'), ('propertyName', 'SportsLogos.net team ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3712'), ('propertyName', 'objective of project or action')]
# [('property', 'http://www.wikidata.org/prop/direct/P3789'), ('propertyName', 'Telegram username')]
# [('property', 'http://www.wikidata.org/prop/direct/P437'), ('propertyName', 'distribution format')]
# [('property', 'http://www.wikidata.org/prop/direct/P61'), ('propertyName', 'discoverer or inventor')]
# [('property', 'http://www.wikidata.org/prop/direct/P7959'), ('propertyName', 'historic county')]
# [('property', 'http://www.wikidata.org/prop/direct/P5513'), ('propertyName', "Enciclopèdia de l'Esport Català ID")]
# [('property', 'http://www.wikidata.org/prop/direct/P4160'), ('propertyName', 'Michelin Restaurants ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P840'), ('propertyName', 'narrative location')]
# [('property', 'http://www.wikidata.org/prop/direct/P144'), ('propertyName', 'based on')]
# [('property', 'http://www.wikidata.org/prop/direct/P291'), ('propertyName', 'place of publication')]
# [('property', 'http://www.wikidata.org/prop/direct/P902'), ('propertyName', 'HDS ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6762'), ('propertyName', 'FilmFreeway ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2966'), ('propertyName', 'National Library of Wales Authority ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P735'), ('propertyName', 'given name')]
# [('property', 'http://www.wikidata.org/prop/direct/P1071'), ('propertyName', 'location of creation')]
# [('property', 'http://www.wikidata.org/prop/direct/P6437'), ('propertyName', 'day of regular release')]
# [('property', 'http://www.wikidata.org/prop/direct/P3407'), ('propertyName', 'Klosterdatenbank ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1535'), ('propertyName', 'used by')]
# [('property', 'http://www.wikidata.org/prop/direct/P1128'), ('propertyName', 'employees')]
# [('property', 'http://www.wikidata.org/prop/direct/P1013'), ('propertyName', 'criterion used')]
# [('property', 'http://www.wikidata.org/prop/direct/P4300'), ('propertyName', 'YouTube playlist ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4353'), ('propertyName', 'nominated by')]
# [('property', 'http://www.wikidata.org/prop/direct/P3040'), ('propertyName', 'SoundCloud ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P94'), ('propertyName', 'coat of arms image')]
# [('property', 'http://www.wikidata.org/prop/direct/P6885'), ('propertyName', 'historical region')]
# [('property', 'http://www.wikidata.org/prop/direct/P2936'), ('propertyName', 'language used')]
# [('property', 'http://www.wikidata.org/prop/direct/P706'), ('propertyName', 'located in/on physical feature')]
# [('property', 'http://www.wikidata.org/prop/direct/P7644'), ('propertyName', 'Encyclopedia of Cleveland History ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3424'), ('propertyName', 'Polish cultural heritage register number')]
# [('property', 'http://www.wikidata.org/prop/direct/P1435'), ('propertyName', 'heritage designation')]
# [('property', 'http://www.wikidata.org/prop/direct/P149'), ('propertyName', 'architectural style')]
# [('property', 'http://www.wikidata.org/prop/direct/P172'), ('propertyName', 'ethnic group')]
# [('property', 'http://www.wikidata.org/prop/direct/P2186'), ('propertyName', 'Wiki Loves Monuments ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4115'), ('propertyName', 'INSPIRE ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P9629'), ('propertyName', 'Armeniapedia ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2596'), ('propertyName', 'culture')]
# [('property', 'http://www.wikidata.org/prop/direct/P3225'), ('propertyName', 'Corporate Number (Japan)')]
# [('property', 'http://www.wikidata.org/prop/direct/P6423'), ('propertyName', 'MusicBrainz event ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1329'), ('propertyName', 'phone number')]
# [('property', 'http://www.wikidata.org/prop/direct/P3749'), ('propertyName', 'Google Maps Customer ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4264'), ('propertyName', 'LinkedIn company ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6010'), ('propertyName', 'Encyclopedia of Alabama ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3638'), ('propertyName', 'Oorlogsmonument ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2142'), ('propertyName', 'box office')]
# [('property', 'http://www.wikidata.org/prop/direct/P2308'), ('propertyName', 'class')]
# [('property', 'http://www.wikidata.org/prop/direct/P1532'), ('propertyName', 'country for sport')]
# [('property', 'http://www.wikidata.org/prop/direct/P1433'), ('propertyName', 'published in')]
# 463

# %%
#Return all awards that have Ian McEwan as winner
queryString = """
SELECT DISTINCT ?award ?awardName ?person
WHERE {
    
    # ?award wdt:P31 wd:Q618779.
    # ?award wdt:P127 wd:Q190379.
    # ?award <http://schema.org/name> ?awardName.

}

"""

print("Results")
run_query(queryString)
# Out:
# Results
# Empty
# 0

# %%
#Return all properties of Paul Auster
queryString = """
SELECT DISTINCT ?property ?propertyName
WHERE {
    
    wd:Q214642 ?property ?object.
    # ?property <http://schema.org/name> ?propertyName.

}

"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('property', 'http://www.wikidata.org/prop/direct/P1005'), ('propertyName', 'Portuguese National Library ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1006'), ('propertyName', 'Nationale Thesaurus voor Auteurs ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P101'), ('propertyName', 'field of work')]
# [('property', 'http://www.wikidata.org/prop/direct/P1015'), ('propertyName', 'NORAF ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P106'), ('propertyName', 'occupation')]
# [('property', 'http://www.wikidata.org/prop/direct/P108'), ('propertyName', 'employer')]
# [('property', 'http://www.wikidata.org/prop/direct/P1150'), ('propertyName', 'Regensburg Classification')]
# [('property', 'http://www.wikidata.org/prop/direct/P1207'), ('propertyName', 'NUKAT ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1233'), ('propertyName', 'Internet Speculative Fiction Database author ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1263'), ('propertyName', 'NNDB people ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1266'), ('propertyName', 'AlloCiné person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1273'), ('propertyName', 'CANTIC ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1280'), ('propertyName', 'CONOR.SI ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1284'), ('propertyName', 'Munzinger person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1289'), ('propertyName', 'Kritisches Lexikon zur fremdsprachigen Gegenwartsliteratur ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1296'), ('propertyName', 'Gran Enciclopèdia Catalana ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1309'), ('propertyName', 'EGAXA ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1315'), ('propertyName', 'NLA Trove ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1317'), ('propertyName', 'floruit')]
# [('property', 'http://www.wikidata.org/prop/direct/P1343'), ('propertyName', 'described by source')]
# [('property', 'http://www.wikidata.org/prop/direct/P136'), ('propertyName', 'genre')]
# [('property', 'http://www.wikidata.org/prop/direct/P1368'), ('propertyName', 'LNB ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1412'), ('propertyName', 'languages spoken, written or signed')]
# [('property', 'http://www.wikidata.org/prop/direct/P1417'), ('propertyName', 'Encyclopædia Britannica Online ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1559'), ('propertyName', 'name in native language')]
# [('property', 'http://www.wikidata.org/prop/direct/P1580'), ('propertyName', 'University of Barcelona authority ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P166'), ('propertyName', 'award received')]
# [('property', 'http://www.wikidata.org/prop/direct/P1695'), ('propertyName', 'NLP ID (unique)')]
# [('property', 'http://www.wikidata.org/prop/direct/P1728'), ('propertyName', 'AllMusic artist ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1741'), ('propertyName', 'GTAA ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P18'), ('propertyName', 'image')]
# [('property', 'http://www.wikidata.org/prop/direct/P19'), ('propertyName', 'place of birth')]
# [('property', 'http://www.wikidata.org/prop/direct/P1953'), ('propertyName', 'Discogs artist ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1969'), ('propertyName', 'MovieMeter director ID (former scheme)')]
# [('property', 'http://www.wikidata.org/prop/direct/P1977'), ('propertyName', 'Les Archives du Spectacle Person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2013'), ('propertyName', 'Facebook ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2019'), ('propertyName', 'AllMovie person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2031'), ('propertyName', 'work period (start)')]
# [('property', 'http://www.wikidata.org/prop/direct/P21'), ('propertyName', 'sex or gender')]
# [('property', 'http://www.wikidata.org/prop/direct/P213'), ('propertyName', 'ISNI')]
# [('property', 'http://www.wikidata.org/prop/direct/P214'), ('propertyName', 'VIAF ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2163'), ('propertyName', 'FAST ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2168'), ('propertyName', 'Swedish Film Database person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2174'), ('propertyName', 'Museum of Modern Art artist ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2188'), ('propertyName', 'BiblioNet author ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2191'), ('propertyName', 'Vegetti Catalog of Fantastic Literature NILF ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P227'), ('propertyName', 'GND ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2387'), ('propertyName', 'Elonet person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2435'), ('propertyName', 'PORT person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P244'), ('propertyName', 'Library of Congress authority ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P245'), ('propertyName', 'Union List of Artist Names ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2519'), ('propertyName', 'Scope.dk person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P26'), ('propertyName', 'spouse')]
# [('property', 'http://www.wikidata.org/prop/direct/P2604'), ('propertyName', 'Kinopoisk person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2605'), ('propertyName', 'ČSFD person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2626'), ('propertyName', 'Danish National Filmography person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2638'), ('propertyName', 'TV.com ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P268'), ('propertyName', 'Bibliothèque nationale de France ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P269'), ('propertyName', 'IdRef ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P27'), ('propertyName', 'country of citizenship')]
# [('property', 'http://www.wikidata.org/prop/direct/P271'), ('propertyName', 'CiNii author ID (books)')]
# [('property', 'http://www.wikidata.org/prop/direct/P2734'), ('propertyName', 'Unz Review author ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2924'), ('propertyName', 'Great Russian Encyclopedia Online ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2963'), ('propertyName', 'Goodreads author ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P31'), ('propertyName', 'instance of')]
# [('property', 'http://www.wikidata.org/prop/direct/P3154'), ('propertyName', 'Runeberg author ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3192'), ('propertyName', 'Last.fm ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3219'), ('propertyName', 'Encyclopædia Universalis ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3222'), ('propertyName', 'NE.se ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3348'), ('propertyName', 'National Library of Greece ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3365'), ('propertyName', 'Treccani ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3430'), ('propertyName', 'SNAC ARK ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P345'), ('propertyName', 'IMDb ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P349'), ('propertyName', 'National Diet Library ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3569'), ('propertyName', 'Cultureel Woordenboek ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3630'), ('propertyName', 'Babelio author ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P373'), ('propertyName', 'Commons category')]
# [('property', 'http://www.wikidata.org/prop/direct/P396'), ('propertyName', 'SBN author ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3987'), ('propertyName', 'SHARE Catalogue author ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P40'), ('propertyName', 'child')]
# [('property', 'http://www.wikidata.org/prop/direct/P409'), ('propertyName', 'Libraries Australia ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4293'), ('propertyName', 'PM20 folder ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P434'), ('propertyName', 'MusicBrainz artist ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4342'), ('propertyName', 'Store norske leksikon ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4399'), ('propertyName', 'Itaú Cultural ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P463'), ('propertyName', 'member of')]
# [('property', 'http://www.wikidata.org/prop/direct/P4657'), ('propertyName', 'The Numbers person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4666'), ('propertyName', 'CineMagia person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4985'), ('propertyName', 'TMDb person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5019'), ('propertyName', 'Brockhaus Enzyklopädie online ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5034'), ('propertyName', 'National Library of Korea ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5068'), ('propertyName', 'Flanders Arts Institute person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5357'), ('propertyName', 'The Encyclopedia of Science Fiction ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5377'), ('propertyName', 'Étonnants voyageurs participant ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5408'), ('propertyName', 'Fantastic Fiction author ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5414'), ('propertyName', 'The Paris Review interviewee ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5419'), ('propertyName', 'NYRB contributor ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5491'), ('propertyName', "BD Gest' author ID")]
# [('property', 'http://www.wikidata.org/prop/direct/P5570'), ('propertyName', 'NooSFere author ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5587'), ('propertyName', 'Libris-URI')]
# [('property', 'http://www.wikidata.org/prop/direct/P5617'), ('propertyName', 'Evene ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P569'), ('propertyName', 'date of birth')]
# [('property', 'http://www.wikidata.org/prop/direct/P5739'), ('propertyName', 'Pontificia Università della Santa Croce ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5821'), ('propertyName', 'ArhivX LOD')]
# [('property', 'http://www.wikidata.org/prop/direct/P5882'), ('propertyName', 'Muziekweb performer ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6173'), ('propertyName', 'Bitraga author ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6379'), ('propertyName', 'has works in the collection')]
# [('property', 'http://www.wikidata.org/prop/direct/P646'), ('propertyName', 'Freebase ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P648'), ('propertyName', 'Open Library ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P650'), ('propertyName', 'RKDartists ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6844'), ('propertyName', 'abART person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P69'), ('propertyName', 'educated at')]
# [('property', 'http://www.wikidata.org/prop/direct/P691'), ('propertyName', 'NKCR AUT ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7084'), ('propertyName', 'related category')]
# [('property', 'http://www.wikidata.org/prop/direct/P723'), ('propertyName', 'Digitale Bibliotheek voor de Nederlandse Letteren author ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7293'), ('propertyName', 'PLWABN ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P734'), ('propertyName', 'family name')]
# [('property', 'http://www.wikidata.org/prop/direct/P735'), ('propertyName', 'given name')]
# [('property', 'http://www.wikidata.org/prop/direct/P742'), ('propertyName', 'pseudonym')]
# [('property', 'http://www.wikidata.org/prop/direct/P7433'), ('propertyName', 'FantLab author ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7704'), ('propertyName', 'Europeana entity')]
# [('property', 'http://www.wikidata.org/prop/direct/P7763'), ('propertyName', 'copyright status as a creator')]
# [('property', 'http://www.wikidata.org/prop/direct/P7859'), ('propertyName', 'WorldCat Identities ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7865'), ('propertyName', 'CoBiS author ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7902'), ('propertyName', 'Deutsche Biographie (GND) ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7982'), ('propertyName', 'Hrvatska enciklopedija ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P800'), ('propertyName', 'notable work')]
# [('property', 'http://www.wikidata.org/prop/direct/P8349'), ('propertyName', 'Proleksis enciklopedija ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P856'), ('propertyName', 'official website')]
# [('property', 'http://www.wikidata.org/prop/direct/P866'), ('propertyName', 'Perlentaucher ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P8795'), ('propertyName', 'General Diamond Catalogue ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P8849'), ('propertyName', 'CONOR.BG ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P8851'), ('propertyName', 'CONOR.SR ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P8971'), ('propertyName', 'Cinémathèque québécoise person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P906'), ('propertyName', 'SELIBR ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P910'), ('propertyName', "topic's main category")]
# [('property', 'http://www.wikidata.org/prop/direct/P9141'), ('propertyName', 'Portal da Literatura ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P9251'), ('propertyName', 'Cyprus University of Technology ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P9322'), ('propertyName', 'SVKKL authority ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P950'), ('propertyName', 'Biblioteca Nacional de España ID')]
# 140

# %%
#Return all Paul Auster's receved awards
queryString = """
SELECT DISTINCT ?award ?awardName
WHERE {
    
    wd:Q214642 wdt:P166 ?award.
    # ?award <http://schema.org/name> ?awardName.

}

"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('award', 'http://www.wikidata.org/entity/Q13452531'), ('awardName', 'Commandeur des Arts et des Lettres\u200e')]
# [('award', 'http://www.wikidata.org/entity/Q3332454'), ('awardName', 'Princess of Asturias Literary Prize')]
# [('award', 'http://www.wikidata.org/entity/Q52382875'), ('awardName', 'AAAS Fellow')]
# [('award', 'http://www.wikidata.org/entity/Q1188661'), ('awardName', 'PEN/Faulkner Award for Fiction')]
# [('award', 'http://www.wikidata.org/entity/Q3405076'), ('awardName', 'Prix Médicis for foreign literature')]
# 5

# %%
#Return all Paul Auster's receved awards properties
queryString = """
SELECT DISTINCT ?property ?propertyName
WHERE {
    
    wd:Q214642 wdt:P166 ?award.
    # ?award ?property ?object.
    # ?property <http://schema.org/name> ?propertyName.

}

"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('property', 'http://www.wikidata.org/prop/direct/P3729'), ('propertyName', 'next lower rank')]
# [('property', 'http://www.wikidata.org/prop/direct/P112'), ('propertyName', 'founded by')]
# [('property', 'http://www.wikidata.org/prop/direct/P1417'), ('propertyName', 'Encyclopædia Britannica Online ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P17'), ('propertyName', 'country')]
# [('property', 'http://www.wikidata.org/prop/direct/P18'), ('propertyName', 'image')]
# [('property', 'http://www.wikidata.org/prop/direct/P1889'), ('propertyName', 'different from')]
# [('property', 'http://www.wikidata.org/prop/direct/P2671'), ('propertyName', 'Google Knowledge Graph ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P279'), ('propertyName', 'subclass of')]
# [('property', 'http://www.wikidata.org/prop/direct/P31'), ('propertyName', 'instance of')]
# [('property', 'http://www.wikidata.org/prop/direct/P361'), ('propertyName', 'part of')]
# [('property', 'http://www.wikidata.org/prop/direct/P373'), ('propertyName', 'Commons category')]
# [('property', 'http://www.wikidata.org/prop/direct/P5008'), ('propertyName', 'on focus list of Wikimedia project')]
# [('property', 'http://www.wikidata.org/prop/direct/P569'), ('propertyName', 'date of birth')]
# [('property', 'http://www.wikidata.org/prop/direct/P571'), ('propertyName', 'inception')]
# [('property', 'http://www.wikidata.org/prop/direct/P580'), ('propertyName', 'start time')]
# [('property', 'http://www.wikidata.org/prop/direct/P646'), ('propertyName', 'Freebase ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P856'), ('propertyName', 'official website')]
# [('property', 'http://www.wikidata.org/prop/direct/P859'), ('propertyName', 'sponsor')]
# [('property', 'http://www.wikidata.org/prop/direct/P910'), ('propertyName', "topic's main category")]
# [('property', 'http://www.wikidata.org/prop/direct/P1027'), ('propertyName', 'conferred by')]
# [('property', 'http://www.wikidata.org/prop/direct/P2425'), ('propertyName', 'service ribbon image')]
# [('property', 'http://www.wikidata.org/prop/direct/P2517'), ('propertyName', 'category for recipients of this award')]
# 22

# %%
#Return all Paul Auster's receved awards category related info
queryString = """
SELECT DISTINCT ?object ?objectName
WHERE {
    
    wd:Q214642 wdt:P166 ?award.
    # ?award ?property ?object.
    # ?object <http://schema.org/name> ?objectName.
    
    
    FILTER(?property = wdt:P373 || ?property = wdt:P910)

}

"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('object', 'http://www.wikidata.org/entity/Q8708086'), ('objectName', 'Category:PEN/Faulkner Foundation awards')]
# [('object', 'http://www.wikidata.org/entity/Q6619589'), ('objectName', 'Category:Fellows of the American Academy of Arts and Sciences')]
# [('object', 'http://www.wikidata.org/entity/Q9145202'), ('objectName', 'Category:Commandeurs of the Ordre des Arts et des Lettres')]
# 3

# %%
#Return all Ian McEwan receved awards
queryString = """
SELECT DISTINCT ?award ?awardName
WHERE {
    
    
    wd:Q190379 wdt:P166 ?award.
    # ?award <http://schema.org/name> ?awardName.


}

"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('award', 'http://www.wikidata.org/entity/Q56494487'), ('awardName', 'honorary doctor of the University of Sussex')]
# [('award', 'http://www.wikidata.org/entity/Q5153503'), ('awardName', 'Common Wealth Award of Distinguished Service')]
# [('award', 'http://www.wikidata.org/entity/Q12201477'), ('awardName', 'Commander of the Order of the British Empire')]
# [('award', 'http://www.wikidata.org/entity/Q277787'), ('awardName', 'Jerusalem Prize')]
# [('award', 'http://www.wikidata.org/entity/Q39477935'), ('awardName', 'Fellow of the Royal Society of Literature')]
# [('award', 'http://www.wikidata.org/entity/Q52382875'), ('awardName', 'AAAS Fellow')]
# [('award', 'http://www.wikidata.org/entity/Q15271633'), ('awardName', 'Fellow of the Royal Society of Arts')]
# [('award', 'http://www.wikidata.org/entity/Q160082'), ('awardName', 'Booker Prize')]
# [('award', 'http://www.wikidata.org/entity/Q392586'), ('awardName', 'James Tait Black Memorial Prize')]
# [('award', 'http://www.wikidata.org/entity/Q5709276'), ('awardName', 'Helmerich Award')]
# [('award', 'http://www.wikidata.org/entity/Q3404580'), ('awardName', 'Prix Femina étranger')]
# [('award', 'http://www.wikidata.org/entity/Q4936657'), ('awardName', 'Bodley Medal')]
# [('award', 'http://www.wikidata.org/entity/Q50622024'), ('awardName', 'honorary doctorate of Carlos III University')]
# [('award', 'http://www.wikidata.org/entity/Q891461'), ('awardName', 'Bollinger Everyman Wodehouse Prize')]
# [('award', 'http://www.wikidata.org/entity/Q7462809'), ('awardName', 'Shakespeare Prize')]
# 15

# %%
#Return all properties connecting awards to Paul Auster
queryString = """
SELECT DISTINCT ?property ?propertyName
WHERE {
    
    # ?award wdt:P31 wd:Q618779.
    # ?award ?property wd:Q214642.
    # ?property <http://schema.org/name> ?propertyName.

}

"""

print("Results")
run_query(queryString)
# Out:
# Results
# Empty
# 0

# %%
#Return all properties  connecting Paul Auster to awards
queryString = """
SELECT DISTINCT ?property ?propertyName
WHERE {
    
    # ?award wdt:P31 wd:Q618779.
    wd:Q214642 ?property ?award.
    # ?property <http://schema.org/name> ?propertyName.

}

"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('property', 'http://www.wikidata.org/prop/direct/P463'), ('propertyName', 'member of')]
# 1

# %%
#Return all awards won by Paul Auster and Ian McEwan
queryString = """
SELECT DISTINCT ?author ?awardName
WHERE {
    
    {
        wd:Q190379 wdt:P166 ?award.
        wd:Q190379 wdt:P1559 ?author.
        # ?award <http://schema.org/name> ?awardName.
    }
    UNION
    {
        wd:Q214642 wdt:P166 ?award.
        wd:Q214642 wdt:P1559 ?author.
        # ?award <http://schema.org/name> ?awardName.
    }


}
ORDER BY (?author)

"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('author', 'Ian McEwan'), ('awardName', 'honorary doctor of the University of Sussex')]
# [('author', 'Ian McEwan'), ('awardName', 'Common Wealth Award of Distinguished Service')]
# [('author', 'Ian McEwan'), ('awardName', 'Commander of the Order of the British Empire')]
# [('author', 'Ian McEwan'), ('awardName', 'Jerusalem Prize')]
# [('author', 'Ian McEwan'), ('awardName', 'Fellow of the Royal Society of Literature')]
# [('author', 'Ian McEwan'), ('awardName', 'AAAS Fellow')]
# [('author', 'Ian McEwan'), ('awardName', 'Fellow of the Royal Society of Arts')]
# [('author', 'Ian McEwan'), ('awardName', 'Booker Prize')]
# [('author', 'Ian McEwan'), ('awardName', 'James Tait Black Memorial Prize')]
# [('author', 'Ian McEwan'), ('awardName', 'Helmerich Award')]
# [('author', 'Ian McEwan'), ('awardName', 'Prix Femina étranger')]
# [('author', 'Ian McEwan'), ('awardName', 'Bodley Medal')]
# [('author', 'Ian McEwan'), ('awardName', 'honorary doctorate of Carlos III University')]
# [('author', 'Ian McEwan'), ('awardName', 'Bollinger Everyman Wodehouse Prize')]
# [('author', 'Ian McEwan'), ('awardName', 'Shakespeare Prize')]
# [('author', 'Paul Auster'), ('awardName', 'Commandeur des Arts et des Lettres\u200e')]
# [('author', 'Paul Auster'), ('awardName', 'Princess of Asturias Literary Prize')]
# [('author', 'Paul Auster'), ('awardName', 'AAAS Fellow')]
# [('author', 'Paul Auster'), ('awardName', 'PEN/Faulkner Award for Fiction')]
# [('author', 'Paul Auster'), ('awardName', 'Prix Médicis for foreign literature')]
# 20

# %%
#Return all awards won by Paul Auster and Ian McEwan and their superclass name
queryString = """
SELECT DISTINCT ?author ?awardName ?sclassName
WHERE {
    
    {
        wd:Q190379 wdt:P166 ?award.
        wd:Q190379 wdt:P1559 ?author.
        # ?award <http://schema.org/name> ?awardName.
        # ?award wdt:P279 ?superclass.
        # ?superclass <http://schema.org/name> ?sclassName.
    }
    UNION
    {
        wd:Q214642 wdt:P166 ?award.
        wd:Q214642 wdt:P1559 ?author.
        # ?award <http://schema.org/name> ?awardName.
        # ?award wdt:P279 ?superclass.
        # ?superclass <http://schema.org/name> ?sclassName.
    }


}
ORDER BY (?author)

"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('author', 'Ian McEwan'), ('awardName', 'AAAS Fellow'), ('sclassName', 'honorary member')]
# [('author', 'Ian McEwan'), ('awardName', 'honorary doctorate of Carlos III University'), ('sclassName', 'doctor honoris causa')]
# [('author', 'Ian McEwan'), ('awardName', 'honorary doctor of the University of Sussex'), ('sclassName', 'doctor honoris causa')]
# [('author', 'Ian McEwan'), ('awardName', 'Fellow of the Royal Society of Arts'), ('sclassName', 'award')]
# [('author', 'Ian McEwan'), ('awardName', 'Commander of the Order of the British Empire'), ('sclassName', 'commander')]
# [('author', 'Paul Auster'), ('awardName', 'AAAS Fellow'), ('sclassName', 'honorary member')]
# [('author', 'Paul Auster'), ('awardName', 'Prix Médicis for foreign literature'), ('sclassName', 'literary award')]
# [('author', 'Paul Auster'), ('awardName', 'Commandeur des Arts et des Lettres\u200e'), ('sclassName', 'commander')]
# 8

# %%
#Return all awards won by Paul Auster and Ian McEwan related with literature
queryString = """
SELECT DISTINCT ?author ?awardName
WHERE {
    
    {
        wd:Q190379 wdt:P166 ?award.
        wd:Q190379 wdt:P1559 ?author.
        # ?award <http://schema.org/name> ?awardName.
    }
    UNION
    {
        wd:Q214642 wdt:P166 ?award.
        wd:Q214642 wdt:P1559 ?author.
        # ?award <http://schema.org/name> ?awardName.
    }
    
    FILTER(REGEX(?awardName, "[Ll]iter") || REGEX(?awardName, "[Aa]rt") || REGEX(?awardName, "[Ff]iction"))


}
ORDER BY (?author)

"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('author', 'Ian McEwan'), ('awardName', 'Fellow of the Royal Society of Arts')]
# [('author', 'Ian McEwan'), ('awardName', 'Fellow of the Royal Society of Literature')]
# [('author', 'Paul Auster'), ('awardName', 'PEN/Faulkner Award for Fiction')]
# [('author', 'Paul Auster'), ('awardName', 'Commandeur des Arts et des Lettres\u200e')]
# [('author', 'Paul Auster'), ('awardName', 'Princess of Asturias Literary Prize')]
# [('author', 'Paul Auster'), ('awardName', 'Prix Médicis for foreign literature')]
# 6

# %%
#Which author won more literature-related awards?
queryString = """
SELECT ?author (COUNT(?award) AS ?awardsWon)
WHERE {
    
    {
        wd:Q190379 wdt:P166 ?award.
        wd:Q190379 wdt:P1559 ?author.
        # ?award <http://schema.org/name> ?awardName.
    }
    UNION
    {
        wd:Q214642 wdt:P166 ?award.
        wd:Q214642 wdt:P1559 ?author.
        # ?award <http://schema.org/name> ?awardName.
    }
    
    FILTER(REGEX(?awardName, "[Ll]iter") || REGEX(?awardName, "[Aa]rt") || REGEX(?awardName, "[Ff]iction"))


}
GROUP BY (?author)
ORDER BY (?author)

"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('author', 'Ian McEwan'), ('awardsWon', '2')]
# [('author', 'Paul Auster'), ('awardsWon', '4')]
# 2

# %% [markdown]
# #### Point 5a Finish
# DESCRIPTION: I started by searching all awards related to Paul. Then investigate more about the “award” class, trying to find the categories and superclass.
# Then I discover “literary award” wd:Q378427 so I checked the relations of that instance.
# After some other useless queries I decided to restart from the list of all properties of Paul Auster, and I discovered the relations wdt:P166 “award received”. Then in order to find the kind of category of the awards I searched for nodes connected through the relations wdt:P373 “Common category”, wdt:P910 “Main common category”.
# Still, I wasn’t able to find any information that I was sure about.
# At the end I decided to keep all awards of both authors and consider only the ones that have the title that matches the following regex: "[Ll]iter", "[Aa]rt", "[Ff]iction"
#
#
#
# RESULT: The result shows that Paul Auster won more awards.

# %% [markdown]
# #### Point 5b Start

# %%
#Return all awards in the database that contain "Nobel" in the name
queryString = """
SELECT DISTINCT ?award ?awardName
WHERE {
    
    # ?award wdt:P31 wd:Q618779.
    # ?award <http://schema.org/name> ?awardName.
    
    FILTER(REGEX(?awardName,"[Nn]obel"))

}

"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('award', 'http://www.wikidata.org/entity/Q7191'), ('awardName', 'Nobel Prize')]
# [('award', 'http://www.wikidata.org/entity/Q105409333'), ('awardName', '2021 Nobel Peace Prize')]
# [('award', 'http://www.wikidata.org/entity/Q16933544'), ('awardName', 'Michael Nobel Energy Award')]
# [('award', 'http://www.wikidata.org/entity/Q835775'), ('awardName', 'Nobel Laureate Meetings at Lindau')]
# [('award', 'http://www.wikidata.org/entity/Q5453832'), ('awardName', 'First Step to Nobel Prize in Physics')]
# [('award', 'http://www.wikidata.org/entity/Q95586868'), ('awardName', 'Nobel Medal for Physics and Chemistry')]
# [('award', 'http://www.wikidata.org/entity/Q30324704'), ('awardName', '2011 Nobel Prize in Physics')]
# 7

# %%
#Return all properties of all awards database that contain "Nobel" in the name
queryString = """
SELECT DISTINCT ?property ?propertyName
WHERE {
    
    # ?award wdt:P31 wd:Q618779.
    # ?award <http://schema.org/name> ?awardName.
    # ?award ?property ?object.
    # ?property <http://schema.org/name> ?propertyName.
    
    FILTER(REGEX(?awardName,"[Nn]obel"))

}

"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('property', 'http://www.wikidata.org/prop/direct/P1051'), ('propertyName', 'PSH ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P112'), ('propertyName', 'founded by')]
# [('property', 'http://www.wikidata.org/prop/direct/P1151'), ('propertyName', "topic's main Wikimedia portal")]
# [('property', 'http://www.wikidata.org/prop/direct/P1225'), ('propertyName', 'U.S. National Archives Identifier')]
# [('property', 'http://www.wikidata.org/prop/direct/P1245'), ('propertyName', 'OmegaWiki Defined Meaning')]
# [('property', 'http://www.wikidata.org/prop/direct/P1296'), ('propertyName', 'Gran Enciclopèdia Catalana ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1343'), ('propertyName', 'described by source')]
# [('property', 'http://www.wikidata.org/prop/direct/P138'), ('propertyName', 'named after')]
# [('property', 'http://www.wikidata.org/prop/direct/P1417'), ('propertyName', 'Encyclopædia Britannica Online ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1424'), ('propertyName', "topic's main template")]
# [('property', 'http://www.wikidata.org/prop/direct/P1438'), ('propertyName', 'Jewish Encyclopedia ID (Russian)')]
# [('property', 'http://www.wikidata.org/prop/direct/P1617'), ('propertyName', 'BBC Things ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P17'), ('propertyName', 'country')]
# [('property', 'http://www.wikidata.org/prop/direct/P1709'), ('propertyName', 'equivalent class')]
# [('property', 'http://www.wikidata.org/prop/direct/P18'), ('propertyName', 'image')]
# [('property', 'http://www.wikidata.org/prop/direct/P1889'), ('propertyName', 'different from')]
# [('property', 'http://www.wikidata.org/prop/direct/P2002'), ('propertyName', 'Twitter username')]
# [('property', 'http://www.wikidata.org/prop/direct/P2013'), ('propertyName', 'Facebook ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P227'), ('propertyName', 'GND ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2347'), ('propertyName', 'YSO ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2397'), ('propertyName', 'YouTube channel ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P244'), ('propertyName', 'Library of Congress authority ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2738'), ('propertyName', 'disjoint union of')]
# [('property', 'http://www.wikidata.org/prop/direct/P279'), ('propertyName', 'subclass of')]
# [('property', 'http://www.wikidata.org/prop/direct/P2910'), ('propertyName', 'icon')]
# [('property', 'http://www.wikidata.org/prop/direct/P2924'), ('propertyName', 'Great Russian Encyclopedia Online ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2959'), ('propertyName', 'permanent duplicated item')]
# [('property', 'http://www.wikidata.org/prop/direct/P31'), ('propertyName', 'instance of')]
# [('property', 'http://www.wikidata.org/prop/direct/P3106'), ('propertyName', 'Guardian topic ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3221'), ('propertyName', 'New York Times topic ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3222'), ('propertyName', 'NE.se ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3417'), ('propertyName', 'Quora topic ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P349'), ('propertyName', 'National Diet Library ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3509'), ('propertyName', 'Dagens Nyheter topic ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3553'), ('propertyName', 'Zhihu topic ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3630'), ('propertyName', 'Babelio author ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P373'), ('propertyName', 'Commons category')]
# [('property', 'http://www.wikidata.org/prop/direct/P3911'), ('propertyName', 'STW Thesaurus for Economics ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4431'), ('propertyName', 'Google Doodle')]
# [('property', 'http://www.wikidata.org/prop/direct/P444'), ('propertyName', 'review score')]
# [('property', 'http://www.wikidata.org/prop/direct/P4527'), ('propertyName', 'UK Parliament thesaurus ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4854'), ('propertyName', 'Uppslagsverket Finland ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P486'), ('propertyName', 'MeSH descriptor ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5008'), ('propertyName', 'on focus list of Wikimedia project')]
# [('property', 'http://www.wikidata.org/prop/direct/P508'), ('propertyName', 'BNCF Thesaurus ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P527'), ('propertyName', 'has part')]
# [('property', 'http://www.wikidata.org/prop/direct/P5357'), ('propertyName', 'The Encyclopedia of Science Fiction ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5395'), ('propertyName', 'Canadian Encyclopedia article ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P571'), ('propertyName', 'inception')]
# [('property', 'http://www.wikidata.org/prop/direct/P5905'), ('propertyName', 'Comic Vine ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6081'), ('propertyName', 'RIA Novosti reference')]
# [('property', 'http://www.wikidata.org/prop/direct/P6200'), ('propertyName', 'BBC News topic ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6293'), ('propertyName', 'YSA ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P646'), ('propertyName', 'Freebase ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6573'), ('propertyName', 'Klexikon article ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6817'), ('propertyName', 'SVT Play ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6849'), ('propertyName', 'DR topic ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7502'), ('propertyName', 'Golden ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7818'), ('propertyName', 'French Vikidia ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P8309'), ('propertyName', 'Yle topic ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P837'), ('propertyName', 'day in year for periodic occurrence')]
# [('property', 'http://www.wikidata.org/prop/direct/P8408'), ('propertyName', 'KBpedia ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P856'), ('propertyName', 'official website')]
# [('property', 'http://www.wikidata.org/prop/direct/P8687'), ('propertyName', 'social media followers')]
# [('property', 'http://www.wikidata.org/prop/direct/P898'), ('propertyName', 'IPA transcription')]
# [('property', 'http://www.wikidata.org/prop/direct/P910'), ('propertyName', "topic's main category")]
# [('property', 'http://www.wikidata.org/prop/direct/P9100'), ('propertyName', 'GitHub topic')]
# [('property', 'http://www.wikidata.org/prop/direct/P9226'), ('propertyName', 'ARAE ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P9545'), ('propertyName', 'Encyclopedia of China Online Database ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P989'), ('propertyName', 'spoken text audio')]
# [('property', 'http://www.wikidata.org/prop/direct/P1027'), ('propertyName', 'conferred by')]
# [('property', 'http://www.wikidata.org/prop/direct/P2517'), ('propertyName', 'category for recipients of this award')]
# [('property', 'http://www.wikidata.org/prop/direct/P2671'), ('propertyName', 'Google Knowledge Graph ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P276'), ('propertyName', 'location')]
# [('property', 'http://www.wikidata.org/prop/direct/P170'), ('propertyName', 'creator')]
# [('property', 'http://www.wikidata.org/prop/direct/P585'), ('propertyName', 'point in time')]
# 76

# %%
#Have they ever being nominated for a Nobel award?
#Return all properties of all awards database that contain "Nobel" in the name and are connected to Paul Auter or Ian McEwan
queryString = """
SELECT DISTINCT ?author ?property ?propertyName
WHERE {
    {
        # ?award wdt:P31 wd:Q618779.
        # ?award <http://schema.org/name> ?awardName.
        # ?award ?property wd:Q214642.
        wd:Q214642 wdt:P1559 ?author.
        # ?property <http://schema.org/name> ?propertyName.
    }
    UNION
    {
        # ?award wdt:P31 wd:Q618779.
        # ?award <http://schema.org/name> ?awardName.
        # ?award ?property wd:Q190379.
        wd:Q190379 wdt:P1559 ?author.
        # ?property <http://schema.org/name> ?propertyName.
    }
    
    FILTER(REGEX(?awardName,"[Nn]obel"))

}
ORDER BY (?author)

"""

print("Results")
run_query(queryString)
# Out:
# Results
# Empty
# 0

# %%
#Have they ever being nominated for a Nobel award?
#Return all properties of Paul Auter or Ian McEwan that connects some awards in database that contain "Nobel" in the name
queryString = """
SELECT DISTINCT ?author ?property ?propertyName
WHERE {
    {
        # ?award wdt:P31 wd:Q618779.
        # ?award <http://schema.org/name> ?awardName.
        wd:Q214642 ?property ?award.
        wd:Q214642 wdt:P1559 ?author.
        # ?property <http://schema.org/name> ?propertyName.
    }
    UNION
    {
        # ?award wdt:P31 wd:Q618779.
        # ?award <http://schema.org/name> ?awardName.
        wd:Q190379 ?property ?award.
        wd:Q190379 wdt:P1559 ?author.
        # ?property <http://schema.org/name> ?propertyName.
    }
    
    FILTER(REGEX(?awardName,"[Nn]obel"))

}
ORDER BY (?author)

"""

print("Results")
run_query(queryString)
# Out:
# Results
# Empty
# 0

# %% [markdown]
# #### Point 5b Finish
# DESCRIPTION: I started from listing all awards that matches the regex [Nn]obel in the name and their properties.
# Then I tried to connect the nodes Paul and Ian to a node that is a Nobel award without any result in both directions.
#
#
#
# RESULT: The result shows that none has won a Nobel award.

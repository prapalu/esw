# %% [markdown]
# # General instructions
#
# The goal of the project is to materialize a set of **exploratory workloads** over a real-world, large-scale,  open-domain KG: [WikiData](https://www.wikidata.org/wiki/Wikidata:Main_Page)
#
# An exploratory workload  is composed by a set of queries, where each query is related to the information obtained previously.
#
# An exploratory workload starts with a usually vague, open ended question, and does not assume the person issuing the workload has a clear understanding of the data contained in the target database or its structure.
#
# Remeber that:
#
# 1. All the queries must run in the python notebook
# 2. You can use classes and properties only if you find them via a SPARQL query that must be present in the notebook
# 3. You do not delete useless queries. Keep everything that is synthatically valid
#
# ```
# ?p <http://schema.org/name> ?name .
# ```
#
#     is the BGP returning a human-readable name of a property or a class in Wikidata.

# %%
## SETUP used later

from SPARQLWrapper import SPARQLWrapper, JSON


prefixString = """
##-c17c3e4e63-##
PREFIX wd: <http://www.wikidata.org/entity/> 
PREFIX wdt: <http://www.wikidata.org/prop/direct/> 
PREFIX sc: <http://schema.org/>
"""

# select and construct queries
def run_query(queryString):
    to_run = prefixString + "\n" + queryString

    sparql = SPARQLWrapper("http://a256-gc1-02.srv.aau.dk:5820/sparql")
    sparql.setTimeout(300)
    sparql.setReturnFormat(JSON)
    sparql.setQuery(to_run)

    try :
       results = sparql.query()
       json_results = results.convert()
       if len(json_results['results']['bindings'])==0:
          print("Empty")
          return 0
    
       for bindings in json_results['results']['bindings']:
          print( [ (var, value['value'])  for var, value in bindings.items() ] )

       return len(json_results['results']['bindings'])

    except Exception as e :
        print("The operation failed", e)
    
# ASk queries
def run_ask_query(queryString):
    to_run = prefixString + "\n" + queryString

    sparql = SPARQLWrapper("http://a256-gc1-02.srv.aau.dk:5820/sparql")
    sparql.setTimeout(300)
    sparql.setReturnFormat(JSON)
    sparql.setQuery(to_run)

    try :
        return sparql.query().convert()

    except Exception as e :
        print("The operation failed", e)

# %% [markdown]
# # Movie Workflow Series ("Horror Franchises explorative search")
#
# Consider the following exploratory scenario:
#
#
# > we are interested in horror movies, in particular we care about the slasher subgenre, and we want to compare the Halloween and the Friday the 13th francise.
#
# Background knowledge useful for better conducting the search: Halloween is a movie from 1978 with many sequels and the set of Halloween + all the sequels is called the "Halloween franchise". The same considerations hold for Friday the 13th.
#
#
# ## Useful URIs for the current workflow
# The following are given:
#
# | IRI           | Description   | Role      |
# | -----------   | -----------   |-----------|
# | `wdt:P1647`   | subproperty   | predicate |
# | `wdt:P31`     | instance of   | predicate |
# | `wdt:P106`    | profession    | predicate |
# | `wdt:P279`    | subclass      | predicate |
# | `wd:Q221103`     | Halloween       | node |
# | `wd:Q1243029`| Friday the 13th       | node |
#
#
#
#
#
# Also consider
#
# ```
# wd:Q1243029 ?p ?obj .
# ```
#
# is the BGP to retrieve all **properties of Friday the 13th**
#
# The workload should
#
#
# 1. Investigate the workers of the two original movies and check any commonality
#
# 2. Check who was the most famous actor/actress on Halloween and Friday the 13th at the time of the release (e.g., the actor/actress who acted in more movies before and/or the actor/actress who won more academy awards)
#
# 3. Check which actor/actress did more movies after the release of these two films (consider the films separately)
#
# 4. Get all the movies of the two franchises (return year and director)
#
# 5. Who is most involved in a franchise (who did something in the movies, e.g., writer, director, producer)?
#
# 6. Investigate which franchise is highly regarded by the critics overall
#
# 7. Investigate which franchise costed more

# %%
# start your workflow here

# %%
queryString = """
SELECT *
WHERE { 

wd:Q1243029 ?p ?obj .
} 
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('p', 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), ('obj', 'http://wikiba.se/ontology#Item')]
# [('p', 'http://www.wikidata.org/prop/direct-normalized/P244'), ('obj', 'https://id.loc.gov/authorities/names/no98033420')]
# [('p', 'http://www.wikidata.org/prop/direct-normalized/P3212'), ('obj', 'urn:isan:0000-0000-31EA-0000-G-0000-0000-Q')]
# [('p', 'http://www.wikidata.org/prop/direct-normalized/P4276'), ('obj', 'https://data.cinematheque.qc.ca/data/Work1467')]
# [('p', 'http://www.wikidata.org/prop/direct-normalized/P646'), ('obj', 'http://g.co/kg/m/016mng')]
# [('p', 'http://www.wikidata.org/prop/direct/P1237'), ('obj', 'friday13th')]
# [('p', 'http://www.wikidata.org/prop/direct/P1258'), ('obj', 'm/friday_the_13th_part_1')]
# [('p', 'http://www.wikidata.org/prop/direct/P1265'), ('obj', '505')]
# [('p', 'http://www.wikidata.org/prop/direct/P136'), ('obj', 'http://www.wikidata.org/entity/Q1067324')]
# [('p', 'http://www.wikidata.org/prop/direct/P136'), ('obj', 'http://www.wikidata.org/entity/Q1200678')]
# [('p', 'http://www.wikidata.org/prop/direct/P136'), ('obj', 'http://www.wikidata.org/entity/Q853630')]
# [('p', 'http://www.wikidata.org/prop/direct/P136'), ('obj', 'http://www.wikidata.org/entity/Q909586')]
# [('p', 'http://www.wikidata.org/prop/direct/P1411'), ('obj', 'http://www.wikidata.org/entity/Q1780634')]
# [('p', 'http://www.wikidata.org/prop/direct/P1411'), ('obj', 'http://www.wikidata.org/entity/Q977915')]
# [('p', 'http://www.wikidata.org/prop/direct/P1476'), ('obj', 'Friday the 13th')]
# [('p', 'http://www.wikidata.org/prop/direct/P156'), ('obj', 'http://www.wikidata.org/entity/Q1243009')]
# [('p', 'http://www.wikidata.org/prop/direct/P1562'), ('obj', 'v18658')]
# [('p', 'http://www.wikidata.org/prop/direct/P161'), ('obj', 'http://www.wikidata.org/entity/Q2440012')]
# [('p', 'http://www.wikidata.org/prop/direct/P161'), ('obj', 'http://www.wikidata.org/entity/Q263765')]
# [('p', 'http://www.wikidata.org/prop/direct/P161'), ('obj', 'http://www.wikidata.org/entity/Q3428829')]
# [('p', 'http://www.wikidata.org/prop/direct/P161'), ('obj', 'http://www.wikidata.org/entity/Q3434272')]
# [('p', 'http://www.wikidata.org/prop/direct/P161'), ('obj', 'http://www.wikidata.org/entity/Q3454165')]
# [('p', 'http://www.wikidata.org/prop/direct/P161'), ('obj', 'http://www.wikidata.org/entity/Q13218111')]
# [('p', 'http://www.wikidata.org/prop/direct/P161'), ('obj', 'http://www.wikidata.org/entity/Q2570201')]
# [('p', 'http://www.wikidata.org/prop/direct/P161'), ('obj', 'http://www.wikidata.org/entity/Q3047636')]
# [('p', 'http://www.wikidata.org/prop/direct/P161'), ('obj', 'http://www.wikidata.org/entity/Q524486')]
# [('p', 'http://www.wikidata.org/prop/direct/P162'), ('obj', 'http://www.wikidata.org/entity/Q709325')]
# [('p', 'http://www.wikidata.org/prop/direct/P1712'), ('obj', 'movie/friday-the-13th-1980')]
# [('p', 'http://www.wikidata.org/prop/direct/P175'), ('obj', 'http://www.wikidata.org/entity/Q664025')]
# [('p', 'http://www.wikidata.org/prop/direct/P179'), ('obj', 'http://www.wikidata.org/entity/Q1138878')]
# [('p', 'http://www.wikidata.org/prop/direct/P18'), ('obj', 'http://commons.wikimedia.org/wiki/Special:FilePath/Friday%20the%2013th%20%281980%29%20film%20logo.png')]
# [('p', 'http://www.wikidata.org/prop/direct/P1804'), ('obj', '1319')]
# [('p', 'http://www.wikidata.org/prop/direct/P1874'), ('obj', '525111')]
# [('p', 'http://www.wikidata.org/prop/direct/P1889'), ('obj', 'http://www.wikidata.org/entity/Q1454815')]
# [('p', 'http://www.wikidata.org/prop/direct/P1970'), ('obj', '1191')]
# [('p', 'http://www.wikidata.org/prop/direct/P2047'), ('obj', '91')]
# [('p', 'http://www.wikidata.org/prop/direct/P2061'), ('obj', 'http://www.wikidata.org/entity/Q752245')]
# [('p', 'http://www.wikidata.org/prop/direct/P2334'), ('obj', '7782')]
# [('p', 'http://www.wikidata.org/prop/direct/P2346'), ('obj', '133662')]
# [('p', 'http://www.wikidata.org/prop/direct/P244'), ('obj', 'no98033420')]
# [('p', 'http://www.wikidata.org/prop/direct/P2465'), ('obj', '10511')]
# [('p', 'http://www.wikidata.org/prop/direct/P2508'), ('obj', '4386')]
# [('p', 'http://www.wikidata.org/prop/direct/P2509'), ('obj', 'mv4378')]
# [('p', 'http://www.wikidata.org/prop/direct/P2518'), ('obj', '1265')]
# [('p', 'http://www.wikidata.org/prop/direct/P2529'), ('obj', '23053')]
# [('p', 'http://www.wikidata.org/prop/direct/P2603'), ('obj', '23922')]
# [('p', 'http://www.wikidata.org/prop/direct/P2631'), ('obj', '17974')]
# [('p', 'http://www.wikidata.org/prop/direct/P2638'), ('obj', 'movies/friday-the-13th-1980')]
# [('p', 'http://www.wikidata.org/prop/direct/P2704'), ('obj', '10.5240/7544-6FCA-F299-ECD8-BE4D-A')]
# [('p', 'http://www.wikidata.org/prop/direct/P272'), ('obj', 'http://www.wikidata.org/entity/Q159846')]
# [('p', 'http://www.wikidata.org/prop/direct/P2747'), ('obj', 'http://www.wikidata.org/entity/Q23830579')]
# [('p', 'http://www.wikidata.org/prop/direct/P2755'), ('obj', '52986')]
# [('p', 'http://www.wikidata.org/prop/direct/P2758'), ('obj', 'http://www.wikidata.org/entity/Q23817741')]
# [('p', 'http://www.wikidata.org/prop/direct/P3077'), ('obj', '18183')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('obj', 'http://www.wikidata.org/entity/Q11424')]
# [('p', 'http://www.wikidata.org/prop/direct/P3107'), ('obj', '25470')]
# [('p', 'http://www.wikidata.org/prop/direct/P3129'), ('obj', '651006')]
# [('p', 'http://www.wikidata.org/prop/direct/P3138'), ('obj', '53')]
# [('p', 'http://www.wikidata.org/prop/direct/P3141'), ('obj', 't0003232')]
# [('p', 'http://www.wikidata.org/prop/direct/P3143'), ('obj', '80561')]
# [('p', 'http://www.wikidata.org/prop/direct/P3203'), ('obj', '54093')]
# [('p', 'http://www.wikidata.org/prop/direct/P3212'), ('obj', '0000-0000-31EA-0000-G-0000-0000-Q')]
# [('p', 'http://www.wikidata.org/prop/direct/P3302'), ('obj', '4488')]
# [('p', 'http://www.wikidata.org/prop/direct/P344'), ('obj', 'http://www.wikidata.org/entity/Q4863956')]
# [('p', 'http://www.wikidata.org/prop/direct/P345'), ('obj', 'tt0080761')]
# [('p', 'http://www.wikidata.org/prop/direct/P3593'), ('obj', '56417')]
# [('p', 'http://www.wikidata.org/prop/direct/P364'), ('obj', 'http://www.wikidata.org/entity/Q1860')]
# [('p', 'http://www.wikidata.org/prop/direct/P3804'), ('obj', '123800')]
# [('p', 'http://www.wikidata.org/prop/direct/P3808'), ('obj', 'Friday-the-13th')]
# [('p', 'http://www.wikidata.org/prop/direct/P3844'), ('obj', '1142')]
# [('p', 'http://www.wikidata.org/prop/direct/P3933'), ('obj', '1294128')]
# [('p', 'http://www.wikidata.org/prop/direct/P4276'), ('obj', '1467')]
# [('p', 'http://www.wikidata.org/prop/direct/P4282'), ('obj', '13638')]
# [('p', 'http://www.wikidata.org/prop/direct/P437'), ('obj', 'http://www.wikidata.org/entity/Q723685')]
# [('p', 'http://www.wikidata.org/prop/direct/P4529'), ('obj', '1293143')]
# [('p', 'http://www.wikidata.org/prop/direct/P462'), ('obj', 'http://www.wikidata.org/entity/Q22006653')]
# [('p', 'http://www.wikidata.org/prop/direct/P4632'), ('obj', '4569')]
# [('p', 'http://www.wikidata.org/prop/direct/P4665'), ('obj', '6056')]
# [('p', 'http://www.wikidata.org/prop/direct/P480'), ('obj', '265349')]
# [('p', 'http://www.wikidata.org/prop/direct/P4947'), ('obj', '4488')]
# [('p', 'http://www.wikidata.org/prop/direct/P495'), ('obj', 'http://www.wikidata.org/entity/Q30')]
# [('p', 'http://www.wikidata.org/prop/direct/P4969'), ('obj', 'http://www.wikidata.org/entity/Q1454815')]
# [('p', 'http://www.wikidata.org/prop/direct/P5021'), ('obj', 'http://www.wikidata.org/entity/Q4165246')]
# [('p', 'http://www.wikidata.org/prop/direct/P5032'), ('obj', '8684')]
# [('p', 'http://www.wikidata.org/prop/direct/P5099'), ('obj', 'film/venerdi13')]
# [('p', 'http://www.wikidata.org/prop/direct/P5693'), ('obj', '93065')]
# [('p', 'http://www.wikidata.org/prop/direct/P57'), ('obj', 'http://www.wikidata.org/entity/Q709325')]
# [('p', 'http://www.wikidata.org/prop/direct/P577'), ('obj', '1980-05-09T00:00:00Z')]
# [('p', 'http://www.wikidata.org/prop/direct/P577'), ('obj', '1980-10-23T00:00:00Z')]
# [('p', 'http://www.wikidata.org/prop/direct/P577'), ('obj', '1980-11-10T00:00:00Z')]
# [('p', 'http://www.wikidata.org/prop/direct/P5786'), ('obj', 'freitag-der-13')]
# [('p', 'http://www.wikidata.org/prop/direct/P58'), ('obj', 'http://www.wikidata.org/entity/Q7926158')]
# [('p', 'http://www.wikidata.org/prop/direct/P5905'), ('obj', '4025-275')]
# [('p', 'http://www.wikidata.org/prop/direct/P6127'), ('obj', 'friday-the-13th')]
# [('p', 'http://www.wikidata.org/prop/direct/P6262'), ('obj', 'movies:Friday_the_13th_(1980)')]
# [('p', 'http://www.wikidata.org/prop/direct/P6262'), ('obj', 'the80smovies:Friday_the_13th')]
# [('p', 'http://www.wikidata.org/prop/direct/P6398'), ('obj', '305332580')]
# [('p', 'http://www.wikidata.org/prop/direct/P6398'), ('obj', '312028305')]
# [('p', 'http://www.wikidata.org/prop/direct/P646'), ('obj', '/m/016mng')]
# [('p', 'http://www.wikidata.org/prop/direct/P6562'), ('obj', '-er1PNqRLiI')]
# [('p', 'http://www.wikidata.org/prop/direct/P674'), ('obj', 'http://www.wikidata.org/entity/Q2576457')]
# [('p', 'http://www.wikidata.org/prop/direct/P674'), ('obj', 'http://www.wikidata.org/entity/Q366957')]
# [('p', 'http://www.wikidata.org/prop/direct/P750'), ('obj', 'http://www.wikidata.org/entity/Q80948336')]
# [('p', 'http://www.wikidata.org/prop/direct/P750'), ('obj', 'http://www.wikidata.org/entity/Q907311')]
# [('p', 'http://www.wikidata.org/prop/direct/P750'), ('obj', 'http://www.wikidata.org/entity/Q159846')]
# [('p', 'http://www.wikidata.org/prop/direct/P7970'), ('obj', '1MV59a10bc8835dfb67d1a4a2bf5428a03b')]
# [('p', 'http://www.wikidata.org/prop/direct/P8033'), ('obj', 'friday-the-13th-m100051176')]
# [('p', 'http://www.wikidata.org/prop/direct/P840'), ('obj', 'http://www.wikidata.org/entity/Q1408')]
# [('p', 'http://www.wikidata.org/prop/direct/P856'), ('obj', 'http://www.fridaythe13thfilms.com')]
# [('p', 'http://www.wikidata.org/prop/direct/P86'), ('obj', 'http://www.wikidata.org/entity/Q664025')]
# [('p', 'http://www.wikidata.org/prop/direct/P905'), ('obj', '7021')]
# [('p', 'http://www.wikidata.org/prop/direct/P915'), ('obj', 'http://www.wikidata.org/entity/Q1408')]
# [('p', 'http://www.wikidata.org/prop/direct/P9586'), ('obj', 'umc.cmc.4cny06c1e312h2mfd2utrtve2')]
# [('p', 'http://schema.org/name'), ('obj', 'Friday the 13th')]
# [('p', 'http://www.wikidata.org/prop/direct/P2554'), ('obj', 'http://www.wikidata.org/entity/Q450964')]
# [('p', 'http://www.wikidata.org/prop/direct/P4277'), ('obj', '10178')]
# [('p', 'http://www.wikidata.org/prop/direct/P7975'), ('obj', '1283')]
# [('p', 'http://www.wikidata.org/prop/direct/P6466'), ('obj', '98dc6b45-4478-4877-8316-acc3c7f6ae94')]
# 118

# %% [markdown]
# ## Taks 1

# %%
#Investigate the workers of the two original movies and check any commonality:

# %%
# in the first query i see that fridey the 13 was released in 1980

# %%
#here i look if i can find a relationship for worker in a particular movie (Friday)
queryString = """
SELECT ?worker ?rel ?name
WHERE { 

# ?worker ?rel wd:Q1243029.
# ?rel <http://schema.org/name> ?name .
} LIMIT 100
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('worker', 'http://www.wikidata.org/entity/Q219424'), ('rel', 'http://www.wikidata.org/prop/direct/P6166'), ('name', 'quotes work')]
# [('worker', 'http://www.wikidata.org/entity/Q1454815'), ('rel', 'http://www.wikidata.org/prop/direct/P144'), ('name', 'based on')]
# [('worker', 'http://www.wikidata.org/entity/Q366957'), ('rel', 'http://www.wikidata.org/prop/direct/P1441'), ('name', 'present in work')]
# [('worker', 'http://www.wikidata.org/entity/Q2576457'), ('rel', 'http://www.wikidata.org/prop/direct/P1441'), ('name', 'present in work')]
# [('worker', 'http://www.wikidata.org/entity/Q1243009'), ('rel', 'http://www.wikidata.org/prop/direct/P155'), ('name', 'follows')]
# [('worker', 'http://www.wikidata.org/entity/Q3567621'), ('rel', 'http://www.wikidata.org/prop/direct/P161'), ('name', 'cast member')]
# 6

# %%
#i investigate the relationship with the film Friday
queryString = """
SELECT ?p ?rel ?name
WHERE { 

wd:Q1243029 ?rel ?p.
# ?rel <http://schema.org/name> ?name .
} LIMIT 200
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('p', 'friday13th'), ('rel', 'http://www.wikidata.org/prop/direct/P1237'), ('name', 'Box Office Mojo film ID (former scheme)')]
# [('p', 'm/friday_the_13th_part_1'), ('rel', 'http://www.wikidata.org/prop/direct/P1258'), ('name', 'Rotten Tomatoes ID')]
# [('p', '505'), ('rel', 'http://www.wikidata.org/prop/direct/P1265'), ('name', 'AlloCiné film ID')]
# [('p', 'http://www.wikidata.org/entity/Q1067324'), ('rel', 'http://www.wikidata.org/prop/direct/P136'), ('name', 'genre')]
# [('p', 'http://www.wikidata.org/entity/Q1200678'), ('rel', 'http://www.wikidata.org/prop/direct/P136'), ('name', 'genre')]
# [('p', 'http://www.wikidata.org/entity/Q853630'), ('rel', 'http://www.wikidata.org/prop/direct/P136'), ('name', 'genre')]
# [('p', 'http://www.wikidata.org/entity/Q909586'), ('rel', 'http://www.wikidata.org/prop/direct/P136'), ('name', 'genre')]
# [('p', 'http://www.wikidata.org/entity/Q1780634'), ('rel', 'http://www.wikidata.org/prop/direct/P1411'), ('name', 'nominated for')]
# [('p', 'http://www.wikidata.org/entity/Q977915'), ('rel', 'http://www.wikidata.org/prop/direct/P1411'), ('name', 'nominated for')]
# [('p', 'Friday the 13th'), ('rel', 'http://www.wikidata.org/prop/direct/P1476'), ('name', 'title')]
# [('p', 'http://www.wikidata.org/entity/Q1243009'), ('rel', 'http://www.wikidata.org/prop/direct/P156'), ('name', 'followed by')]
# [('p', 'v18658'), ('rel', 'http://www.wikidata.org/prop/direct/P1562'), ('name', 'AllMovie title ID')]
# [('p', 'http://www.wikidata.org/entity/Q2440012'), ('rel', 'http://www.wikidata.org/prop/direct/P161'), ('name', 'cast member')]
# [('p', 'http://www.wikidata.org/entity/Q263765'), ('rel', 'http://www.wikidata.org/prop/direct/P161'), ('name', 'cast member')]
# [('p', 'http://www.wikidata.org/entity/Q3428829'), ('rel', 'http://www.wikidata.org/prop/direct/P161'), ('name', 'cast member')]
# [('p', 'http://www.wikidata.org/entity/Q3434272'), ('rel', 'http://www.wikidata.org/prop/direct/P161'), ('name', 'cast member')]
# [('p', 'http://www.wikidata.org/entity/Q3454165'), ('rel', 'http://www.wikidata.org/prop/direct/P161'), ('name', 'cast member')]
# [('p', 'http://www.wikidata.org/entity/Q13218111'), ('rel', 'http://www.wikidata.org/prop/direct/P161'), ('name', 'cast member')]
# [('p', 'http://www.wikidata.org/entity/Q2570201'), ('rel', 'http://www.wikidata.org/prop/direct/P161'), ('name', 'cast member')]
# [('p', 'http://www.wikidata.org/entity/Q3047636'), ('rel', 'http://www.wikidata.org/prop/direct/P161'), ('name', 'cast member')]
# [('p', 'http://www.wikidata.org/entity/Q524486'), ('rel', 'http://www.wikidata.org/prop/direct/P161'), ('name', 'cast member')]
# [('p', 'http://www.wikidata.org/entity/Q709325'), ('rel', 'http://www.wikidata.org/prop/direct/P162'), ('name', 'producer')]
# [('p', 'movie/friday-the-13th-1980'), ('rel', 'http://www.wikidata.org/prop/direct/P1712'), ('name', 'Metacritic ID')]
# [('p', 'http://www.wikidata.org/entity/Q664025'), ('rel', 'http://www.wikidata.org/prop/direct/P175'), ('name', 'performer')]
# [('p', 'http://www.wikidata.org/entity/Q1138878'), ('rel', 'http://www.wikidata.org/prop/direct/P179'), ('name', 'part of the series')]
# [('p', 'http://commons.wikimedia.org/wiki/Special:FilePath/Friday%20the%2013th%20%281980%29%20film%20logo.png'), ('rel', 'http://www.wikidata.org/prop/direct/P18'), ('name', 'image')]
# [('p', '1319'), ('rel', 'http://www.wikidata.org/prop/direct/P1804'), ('name', 'DNF film ID')]
# [('p', '525111'), ('rel', 'http://www.wikidata.org/prop/direct/P1874'), ('name', 'Netflix ID')]
# [('p', 'http://www.wikidata.org/entity/Q1454815'), ('rel', 'http://www.wikidata.org/prop/direct/P1889'), ('name', 'different from')]
# [('p', '1191'), ('rel', 'http://www.wikidata.org/prop/direct/P1970'), ('name', 'MovieMeter film ID')]
# [('p', '91'), ('rel', 'http://www.wikidata.org/prop/direct/P2047'), ('name', 'duration')]
# [('p', 'http://www.wikidata.org/entity/Q752245'), ('rel', 'http://www.wikidata.org/prop/direct/P2061'), ('name', 'aspect ratio')]
# [('p', '7782'), ('rel', 'http://www.wikidata.org/prop/direct/P2334'), ('name', 'Swedish Film Database film ID')]
# [('p', '133662'), ('rel', 'http://www.wikidata.org/prop/direct/P2346'), ('name', 'Elonet movie ID')]
# [('p', 'no98033420'), ('rel', 'http://www.wikidata.org/prop/direct/P244'), ('name', 'Library of Congress authority ID')]
# [('p', '10511'), ('rel', 'http://www.wikidata.org/prop/direct/P2465'), ('name', 'Allcinema film ID')]
# [('p', '4386'), ('rel', 'http://www.wikidata.org/prop/direct/P2508'), ('name', 'KINENOTE film ID')]
# [('p', 'mv4378'), ('rel', 'http://www.wikidata.org/prop/direct/P2509'), ('name', 'Movie Walker film ID')]
# [('p', '1265'), ('rel', 'http://www.wikidata.org/prop/direct/P2518'), ('name', 'Scope.dk film ID')]
# [('p', '23053'), ('rel', 'http://www.wikidata.org/prop/direct/P2529'), ('name', 'ČSFD film ID')]
# [('p', '23922'), ('rel', 'http://www.wikidata.org/prop/direct/P2603'), ('name', 'Kinopoisk film ID')]
# [('p', '17974'), ('rel', 'http://www.wikidata.org/prop/direct/P2631'), ('name', 'TCM Movie Database film ID')]
# [('p', 'movies/friday-the-13th-1980'), ('rel', 'http://www.wikidata.org/prop/direct/P2638'), ('name', 'TV.com ID')]
# [('p', '10.5240/7544-6FCA-F299-ECD8-BE4D-A'), ('rel', 'http://www.wikidata.org/prop/direct/P2704'), ('name', 'EIDR content ID')]
# [('p', 'http://www.wikidata.org/entity/Q159846'), ('rel', 'http://www.wikidata.org/prop/direct/P272'), ('name', 'production company')]
# [('p', 'http://www.wikidata.org/entity/Q23830579'), ('rel', 'http://www.wikidata.org/prop/direct/P2747'), ('name', 'Filmiroda rating')]
# [('p', '52986'), ('rel', 'http://www.wikidata.org/prop/direct/P2755'), ('name', 'exploitation visa number')]
# [('p', 'http://www.wikidata.org/entity/Q23817741'), ('rel', 'http://www.wikidata.org/prop/direct/P2758'), ('name', 'CNC film rating (France)')]
# [('p', '18183'), ('rel', 'http://www.wikidata.org/prop/direct/P3077'), ('name', 'Cineplex Germany film ID')]
# [('p', 'http://www.wikidata.org/entity/Q11424'), ('rel', 'http://www.wikidata.org/prop/direct/P31'), ('name', 'instance of')]
# [('p', '25470'), ('rel', 'http://www.wikidata.org/prop/direct/P3107'), ('name', 'LdiF ID')]
# [('p', '651006'), ('rel', 'http://www.wikidata.org/prop/direct/P3129'), ('name', 'cine.gr film ID')]
# [('p', '53'), ('rel', 'http://www.wikidata.org/prop/direct/P3138'), ('name', 'OFDb film ID')]
# [('p', 't0003232'), ('rel', 'http://www.wikidata.org/prop/direct/P3141'), ('name', 'EDb film ID')]
# [('p', '80561'), ('rel', 'http://www.wikidata.org/prop/direct/P3143'), ('name', 'elFilm film ID')]
# [('p', '54093'), ('rel', 'http://www.wikidata.org/prop/direct/P3203'), ('name', 'Ciné-Ressources film ID')]
# [('p', '0000-0000-31EA-0000-G-0000-0000-Q'), ('rel', 'http://www.wikidata.org/prop/direct/P3212'), ('name', 'ISAN')]
# [('p', '4488'), ('rel', 'http://www.wikidata.org/prop/direct/P3302'), ('name', 'Open Media Database film ID')]
# [('p', 'http://www.wikidata.org/entity/Q4863956'), ('rel', 'http://www.wikidata.org/prop/direct/P344'), ('name', 'director of photography')]
# [('p', 'tt0080761'), ('rel', 'http://www.wikidata.org/prop/direct/P345'), ('name', 'IMDb ID')]
# [('p', '56417'), ('rel', 'http://www.wikidata.org/prop/direct/P3593'), ('name', 'AFI Catalog of Feature Films ID')]
# [('p', 'http://www.wikidata.org/entity/Q1860'), ('rel', 'http://www.wikidata.org/prop/direct/P364'), ('name', 'original language of film or TV show')]
# [('p', '123800'), ('rel', 'http://www.wikidata.org/prop/direct/P3804'), ('name', 'TV Guide show ID (former scheme)')]
# [('p', 'Friday-the-13th'), ('rel', 'http://www.wikidata.org/prop/direct/P3808'), ('name', 'The Numbers movie ID')]
# [('p', '1142'), ('rel', 'http://www.wikidata.org/prop/direct/P3844'), ('name', 'Deutsche Synchronkartei film ID')]
# [('p', '1294128'), ('rel', 'http://www.wikidata.org/prop/direct/P3933'), ('name', 'Cinema.de ID')]
# [('p', '1467'), ('rel', 'http://www.wikidata.org/prop/direct/P4276'), ('name', 'Cinémathèque québécoise work identifier')]
# [('p', '13638'), ('rel', 'http://www.wikidata.org/prop/direct/P4282'), ('name', 'LUMIERE film ID')]
# [('p', 'http://www.wikidata.org/entity/Q723685'), ('rel', 'http://www.wikidata.org/prop/direct/P437'), ('name', 'distribution format')]
# [('p', '1293143'), ('rel', 'http://www.wikidata.org/prop/direct/P4529'), ('name', 'Douban film ID')]
# [('p', 'http://www.wikidata.org/entity/Q22006653'), ('rel', 'http://www.wikidata.org/prop/direct/P462'), ('name', 'color')]
# [('p', '4569'), ('rel', 'http://www.wikidata.org/prop/direct/P4632'), ('name', 'Bechdel Test Movie List ID')]
# [('p', '6056'), ('rel', 'http://www.wikidata.org/prop/direct/P4665'), ('name', 'CineMagia title ID')]
# [('p', '265349'), ('rel', 'http://www.wikidata.org/prop/direct/P480'), ('name', 'FilmAffinity ID')]
# [('p', '4488'), ('rel', 'http://www.wikidata.org/prop/direct/P4947'), ('name', 'TMDb movie ID')]
# [('p', 'http://www.wikidata.org/entity/Q30'), ('rel', 'http://www.wikidata.org/prop/direct/P495'), ('name', 'country of origin')]
# [('p', 'http://www.wikidata.org/entity/Q1454815'), ('rel', 'http://www.wikidata.org/prop/direct/P4969'), ('name', 'derivative work')]
# [('p', 'http://www.wikidata.org/entity/Q4165246'), ('rel', 'http://www.wikidata.org/prop/direct/P5021'), ('name', 'assessment')]
# [('p', '8684'), ('rel', 'http://www.wikidata.org/prop/direct/P5032'), ('name', 'Filmweb.pl film ID')]
# [('p', 'film/venerdi13'), ('rel', 'http://www.wikidata.org/prop/direct/P5099'), ('name', 'Il mondo dei doppiatori ID')]
# [('p', '93065'), ('rel', 'http://www.wikidata.org/prop/direct/P5693'), ('name', 'Fandango film ID')]
# [('p', 'http://www.wikidata.org/entity/Q709325'), ('rel', 'http://www.wikidata.org/prop/direct/P57'), ('name', 'director')]
# [('p', '1980-05-09T00:00:00Z'), ('rel', 'http://www.wikidata.org/prop/direct/P577'), ('name', 'publication date')]
# [('p', '1980-10-23T00:00:00Z'), ('rel', 'http://www.wikidata.org/prop/direct/P577'), ('name', 'publication date')]
# [('p', '1980-11-10T00:00:00Z'), ('rel', 'http://www.wikidata.org/prop/direct/P577'), ('name', 'publication date')]
# [('p', 'freitag-der-13'), ('rel', 'http://www.wikidata.org/prop/direct/P5786'), ('name', 'Moviepilot.de film ID')]
# [('p', 'http://www.wikidata.org/entity/Q7926158'), ('rel', 'http://www.wikidata.org/prop/direct/P58'), ('name', 'screenwriter')]
# [('p', '4025-275'), ('rel', 'http://www.wikidata.org/prop/direct/P5905'), ('name', 'Comic Vine ID')]
# [('p', 'friday-the-13th'), ('rel', 'http://www.wikidata.org/prop/direct/P6127'), ('name', 'Letterboxd film ID')]
# [('p', 'movies:Friday_the_13th_(1980)'), ('rel', 'http://www.wikidata.org/prop/direct/P6262'), ('name', 'Fandom article ID')]
# [('p', 'the80smovies:Friday_the_13th'), ('rel', 'http://www.wikidata.org/prop/direct/P6262'), ('name', 'Fandom article ID')]
# [('p', '305332580'), ('rel', 'http://www.wikidata.org/prop/direct/P6398'), ('name', 'iTunes movie ID')]
# [('p', '312028305'), ('rel', 'http://www.wikidata.org/prop/direct/P6398'), ('name', 'iTunes movie ID')]
# [('p', '/m/016mng'), ('rel', 'http://www.wikidata.org/prop/direct/P646'), ('name', 'Freebase ID')]
# [('p', '-er1PNqRLiI'), ('rel', 'http://www.wikidata.org/prop/direct/P6562'), ('name', 'Google Play Movies & TV ID')]
# [('p', 'http://www.wikidata.org/entity/Q2576457'), ('rel', 'http://www.wikidata.org/prop/direct/P674'), ('name', 'characters')]
# [('p', 'http://www.wikidata.org/entity/Q366957'), ('rel', 'http://www.wikidata.org/prop/direct/P674'), ('name', 'characters')]
# [('p', 'http://www.wikidata.org/entity/Q80948336'), ('rel', 'http://www.wikidata.org/prop/direct/P750'), ('name', 'distributed by')]
# [('p', 'http://www.wikidata.org/entity/Q907311'), ('rel', 'http://www.wikidata.org/prop/direct/P750'), ('name', 'distributed by')]
# [('p', 'http://www.wikidata.org/entity/Q159846'), ('rel', 'http://www.wikidata.org/prop/direct/P750'), ('name', 'distributed by')]
# [('p', '1MV59a10bc8835dfb67d1a4a2bf5428a03b'), ('rel', 'http://www.wikidata.org/prop/direct/P7970'), ('name', 'FandangoNow ID')]
# [('p', 'friday-the-13th-m100051176'), ('rel', 'http://www.wikidata.org/prop/direct/P8033'), ('name', 'Movie Review Query Engine ID')]
# [('p', 'http://www.wikidata.org/entity/Q1408'), ('rel', 'http://www.wikidata.org/prop/direct/P840'), ('name', 'narrative location')]
# [('p', 'http://www.fridaythe13thfilms.com'), ('rel', 'http://www.wikidata.org/prop/direct/P856'), ('name', 'official website')]
# [('p', 'http://www.wikidata.org/entity/Q664025'), ('rel', 'http://www.wikidata.org/prop/direct/P86'), ('name', 'composer')]
# [('p', '7021'), ('rel', 'http://www.wikidata.org/prop/direct/P905'), ('name', 'PORT film ID')]
# [('p', 'http://www.wikidata.org/entity/Q1408'), ('rel', 'http://www.wikidata.org/prop/direct/P915'), ('name', 'filming location')]
# [('p', 'umc.cmc.4cny06c1e312h2mfd2utrtve2'), ('rel', 'http://www.wikidata.org/prop/direct/P9586'), ('name', 'Apple TV movie ID')]
# [('p', 'http://www.wikidata.org/entity/Q450964'), ('rel', 'http://www.wikidata.org/prop/direct/P2554'), ('name', 'production designer')]
# [('p', '10178'), ('rel', 'http://www.wikidata.org/prop/direct/P4277'), ('name', 'Daum movie ID')]
# [('p', '1283'), ('rel', 'http://www.wikidata.org/prop/direct/P7975'), ('name', 'Filmfront film ID')]
# [('p', '98dc6b45-4478-4877-8316-acc3c7f6ae94'), ('rel', 'http://www.wikidata.org/prop/direct/P6466'), ('name', 'Hulu movie ID')]
# 112

# %%
#in the query before i found the iri for publication date which is P577
#Check who was the most famous actor/actress on Halloween and Friday the 13th at the time of the release
#(e.g., the actor/actress who acted in more movies before and/or the actor/actress who won more academy awards)
# In the previous query i found the iri for cast member which is P161
#here i find also the iri for director P57

# %%
#in the query before i get the iri P179 which stands for part of the series , screen writer P58, director P57, director of photography P344
#performer P175,producer P162,production designer P2554,composer P86

# %%
#i investigate the relationship with the film halloween
queryString = """
SELECT ?p ?rel ?name
WHERE { 

wd:Q221103 ?rel ?p.
# ?rel <http://schema.org/name> ?name .
} LIMIT 200
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/entity/Q574983'), ('rel', 'http://www.wikidata.org/prop/direct/P1040'), ('name', 'film editor')]
# [('p', 'halloween'), ('rel', 'http://www.wikidata.org/prop/direct/P1237'), ('name', 'Box Office Mojo film ID (former scheme)')]
# [('p', 'm/1009113-halloween'), ('rel', 'http://www.wikidata.org/prop/direct/P1258'), ('name', 'Rotten Tomatoes ID')]
# [('p', '9434'), ('rel', 'http://www.wikidata.org/prop/direct/P1265'), ('name', 'AlloCiné film ID')]
# [('p', 'http://www.wikidata.org/entity/Q377616'), ('rel', 'http://www.wikidata.org/prop/direct/P135'), ('name', 'movement')]
# [('p', 'http://www.wikidata.org/entity/Q130232'), ('rel', 'http://www.wikidata.org/prop/direct/P136'), ('name', 'genre')]
# [('p', 'http://www.wikidata.org/entity/Q200092'), ('rel', 'http://www.wikidata.org/prop/direct/P136'), ('name', 'genre')]
# [('p', 'http://www.wikidata.org/entity/Q1146335'), ('rel', 'http://www.wikidata.org/prop/direct/P136'), ('name', 'genre')]
# [('p', 'http://www.wikidata.org/entity/Q853630'), ('rel', 'http://www.wikidata.org/prop/direct/P136'), ('name', 'genre')]
# [('p', 'topic/Halloween-1978-film'), ('rel', 'http://www.wikidata.org/prop/direct/P1417'), ('name', 'Encyclopædia Britannica Online ID')]
# [('p', 'http://www.wikidata.org/entity/Q101480110'), ('rel', 'http://www.wikidata.org/prop/direct/P1434'), ('name', 'takes place in fictional universe')]
# [('p', 'Halloween'), ('rel', 'http://www.wikidata.org/prop/direct/P1476'), ('name', 'title')]
# [('p', 'http://www.wikidata.org/entity/Q850312'), ('rel', 'http://www.wikidata.org/prop/direct/P156'), ('name', 'followed by')]
# [('p', 'v21317'), ('rel', 'http://www.wikidata.org/prop/direct/P1562'), ('name', 'AllMovie title ID')]
# [('p', 'http://www.wikidata.org/entity/Q2865227'), ('rel', 'http://www.wikidata.org/prop/direct/P161'), ('name', 'cast member')]
# [('p', 'http://www.wikidata.org/entity/Q3066766'), ('rel', 'http://www.wikidata.org/prop/direct/P161'), ('name', 'cast member')]
# [('p', 'http://www.wikidata.org/entity/Q106997'), ('rel', 'http://www.wikidata.org/prop/direct/P161'), ('name', 'cast member')]
# [('p', 'http://www.wikidata.org/entity/Q201570'), ('rel', 'http://www.wikidata.org/prop/direct/P161'), ('name', 'cast member')]
# [('p', 'http://www.wikidata.org/entity/Q1064022'), ('rel', 'http://www.wikidata.org/prop/direct/P161'), ('name', 'cast member')]
# [('p', 'http://www.wikidata.org/entity/Q95008'), ('rel', 'http://www.wikidata.org/prop/direct/P161'), ('name', 'cast member')]
# [('p', 'http://www.wikidata.org/entity/Q936000'), ('rel', 'http://www.wikidata.org/prop/direct/P161'), ('name', 'cast member')]
# [('p', 'http://www.wikidata.org/entity/Q1853959'), ('rel', 'http://www.wikidata.org/prop/direct/P161'), ('name', 'cast member')]
# [('p', 'http://www.wikidata.org/entity/Q314914'), ('rel', 'http://www.wikidata.org/prop/direct/P161'), ('name', 'cast member')]
# [('p', 'http://www.wikidata.org/entity/Q3093664'), ('rel', 'http://www.wikidata.org/prop/direct/P161'), ('name', 'cast member')]
# [('p', 'http://www.wikidata.org/entity/Q270079'), ('rel', 'http://www.wikidata.org/prop/direct/P161'), ('name', 'cast member')]
# [('p', 'http://www.wikidata.org/entity/Q6963012'), ('rel', 'http://www.wikidata.org/prop/direct/P161'), ('name', 'cast member')]
# [('p', 'http://www.wikidata.org/entity/Q6248629'), ('rel', 'http://www.wikidata.org/prop/direct/P161'), ('name', 'cast member')]
# [('p', 'http://www.wikidata.org/entity/Q262102'), ('rel', 'http://www.wikidata.org/prop/direct/P162'), ('name', 'producer')]
# [('p', 'http://www.wikidata.org/entity/Q380471'), ('rel', 'http://www.wikidata.org/prop/direct/P162'), ('name', 'producer')]
# [('p', 'http://www.wikidata.org/entity/Q3802169'), ('rel', 'http://www.wikidata.org/prop/direct/P162'), ('name', 'producer')]
# [('p', 'http://www.wikidata.org/entity/Q823422'), ('rel', 'http://www.wikidata.org/prop/direct/P166'), ('name', 'award received')]
# [('p', 'movie/halloween-1978'), ('rel', 'http://www.wikidata.org/prop/direct/P1712'), ('name', 'Metacritic ID')]
# [('p', 'http://www.wikidata.org/entity/Q95008'), ('rel', 'http://www.wikidata.org/prop/direct/P175'), ('name', 'performer')]
# [('p', 'http://www.wikidata.org/entity/Q1364022'), ('rel', 'http://www.wikidata.org/prop/direct/P179'), ('name', 'part of the series')]
# [('p', '16863'), ('rel', 'http://www.wikidata.org/prop/direct/P1804'), ('name', 'DNF film ID')]
# [('p', '569090'), ('rel', 'http://www.wikidata.org/prop/direct/P1874'), ('name', 'Netflix ID')]
# [('p', 'http://www.wikidata.org/entity/Q229620'), ('rel', 'http://www.wikidata.org/prop/direct/P1889'), ('name', 'different from')]
# [('p', '1081'), ('rel', 'http://www.wikidata.org/prop/direct/P1970'), ('name', 'MovieMeter film ID')]
# [('p', '91'), ('rel', 'http://www.wikidata.org/prop/direct/P2047'), ('name', 'duration')]
# [('p', 'http://www.wikidata.org/entity/Q21062414'), ('rel', 'http://www.wikidata.org/prop/direct/P2061'), ('name', 'aspect ratio')]
# [('p', '325000'), ('rel', 'http://www.wikidata.org/prop/direct/P2130'), ('name', 'cost')]
# [('p', '183290594'), ('rel', 'http://www.wikidata.org/prop/direct/P214'), ('name', 'VIAF ID')]
# [('p', '7671785-9'), ('rel', 'http://www.wikidata.org/prop/direct/P227'), ('name', 'GND ID')]
# [('p', '8377'), ('rel', 'http://www.wikidata.org/prop/direct/P2334'), ('name', 'Swedish Film Database film ID')]
# [('p', '121090'), ('rel', 'http://www.wikidata.org/prop/direct/P2346'), ('name', 'Elonet movie ID')]
# [('p', 'no98046857'), ('rel', 'http://www.wikidata.org/prop/direct/P244'), ('name', 'Library of Congress authority ID')]
# [('p', '18702'), ('rel', 'http://www.wikidata.org/prop/direct/P2465'), ('name', 'Allcinema film ID')]
# [('p', '7161'), ('rel', 'http://www.wikidata.org/prop/direct/P2508'), ('name', 'KINENOTE film ID')]
# [('p', 'mv7146'), ('rel', 'http://www.wikidata.org/prop/direct/P2509'), ('name', 'Movie Walker film ID')]
# [('p', '2575'), ('rel', 'http://www.wikidata.org/prop/direct/P2518'), ('name', 'Scope.dk film ID')]
# [('p', '1322'), ('rel', 'http://www.wikidata.org/prop/direct/P2529'), ('name', 'ČSFD film ID')]
# [('p', '8435'), ('rel', 'http://www.wikidata.org/prop/direct/P2603'), ('name', 'Kinopoisk film ID')]
# [('p', '77236'), ('rel', 'http://www.wikidata.org/prop/direct/P2631'), ('name', 'TCM Movie Database film ID')]
# [('p', 'movies/halloween'), ('rel', 'http://www.wikidata.org/prop/direct/P2638'), ('name', 'TV.com ID')]
# [('p', '10.5240/F55B-E276-0102-C4C1-93B5-Y'), ('rel', 'http://www.wikidata.org/prop/direct/P2704'), ('name', 'EIDR content ID')]
# [('p', 'http://www.wikidata.org/entity/Q3685076'), ('rel', 'http://www.wikidata.org/prop/direct/P272'), ('name', 'production company')]
# [('p', 'http://www.wikidata.org/entity/Q23830579'), ('rel', 'http://www.wikidata.org/prop/direct/P2747'), ('name', 'Filmiroda rating')]
# [('p', '18105'), ('rel', 'http://www.wikidata.org/prop/direct/P3077'), ('name', 'Cineplex Germany film ID')]
# [('p', 'http://www.wikidata.org/entity/Q11424'), ('rel', 'http://www.wikidata.org/prop/direct/P31'), ('name', 'instance of')]
# [('p', '16452'), ('rel', 'http://www.wikidata.org/prop/direct/P3107'), ('name', 'LdiF ID')]
# [('p', '651007'), ('rel', 'http://www.wikidata.org/prop/direct/P3129'), ('name', 'cine.gr film ID')]
# [('p', '63'), ('rel', 'http://www.wikidata.org/prop/direct/P3138'), ('name', 'OFDb film ID')]
# [('p', 't0003057'), ('rel', 'http://www.wikidata.org/prop/direct/P3141'), ('name', 'EDb film ID')]
# [('p', '77467'), ('rel', 'http://www.wikidata.org/prop/direct/P3143'), ('name', 'elFilm film ID')]
# [('p', '0000-0001-3D3E-0000-E-0000-0000-W'), ('rel', 'http://www.wikidata.org/prop/direct/P3212'), ('name', 'ISAN')]
# [('p', '948'), ('rel', 'http://www.wikidata.org/prop/direct/P3302'), ('name', 'Open Media Database film ID')]
# [('p', 'http://www.wikidata.org/entity/Q497036'), ('rel', 'http://www.wikidata.org/prop/direct/P344'), ('name', 'director of photography')]
# [('p', 'tt0077651'), ('rel', 'http://www.wikidata.org/prop/direct/P345'), ('name', 'IMDb ID')]
# [('p', '56347'), ('rel', 'http://www.wikidata.org/prop/direct/P3593'), ('name', 'AFI Catalog of Feature Films ID')]
# [('p', 'http://www.wikidata.org/entity/Q1860'), ('rel', 'http://www.wikidata.org/prop/direct/P364'), ('name', 'original language of film or TV show')]
# [('p', '125497'), ('rel', 'http://www.wikidata.org/prop/direct/P3804'), ('name', 'TV Guide show ID (former scheme)')]
# [('p', 'Halloween'), ('rel', 'http://www.wikidata.org/prop/direct/P3808'), ('name', 'The Numbers movie ID')]
# [('p', '1392'), ('rel', 'http://www.wikidata.org/prop/direct/P3844'), ('name', 'Deutsche Synchronkartei film ID')]
# [('p', '1331081'), ('rel', 'http://www.wikidata.org/prop/direct/P3933'), ('name', 'Cinema.de ID')]
# [('p', '787'), ('rel', 'http://www.wikidata.org/prop/direct/P4276'), ('name', 'Cinémathèque québécoise work identifier')]
# [('p', '12659'), ('rel', 'http://www.wikidata.org/prop/direct/P4282'), ('name', 'LUMIERE film ID')]
# [('p', 'http://www.wikidata.org/entity/Q723685'), ('rel', 'http://www.wikidata.org/prop/direct/P437'), ('name', 'distribution format')]
# [('p', '1299586'), ('rel', 'http://www.wikidata.org/prop/direct/P4529'), ('name', 'Douban film ID')]
# [('p', 'http://www.wikidata.org/entity/Q22006653'), ('rel', 'http://www.wikidata.org/prop/direct/P462'), ('name', 'color')]
# [('p', '2815'), ('rel', 'http://www.wikidata.org/prop/direct/P4632'), ('name', 'Bechdel Test Movie List ID')]
# [('p', '1774'), ('rel', 'http://www.wikidata.org/prop/direct/P4665'), ('name', 'CineMagia title ID')]
# [('p', '11287'), ('rel', 'http://www.wikidata.org/prop/direct/P4780'), ('name', 'MYmovies movie ID')]
# [('p', '384174'), ('rel', 'http://www.wikidata.org/prop/direct/P480'), ('name', 'FilmAffinity ID')]
# [('p', '948'), ('rel', 'http://www.wikidata.org/prop/direct/P4947'), ('name', 'TMDb movie ID')]
# [('p', 'http://www.wikidata.org/entity/Q30'), ('rel', 'http://www.wikidata.org/prop/direct/P495'), ('name', 'country of origin')]
# [('p', 'http://www.wikidata.org/entity/Q3285065'), ('rel', 'http://www.wikidata.org/prop/direct/P4969'), ('name', 'derivative work')]
# [('p', 'http://www.wikidata.org/entity/Q4502764'), ('rel', 'http://www.wikidata.org/prop/direct/P4969'), ('name', 'derivative work')]
# [('p', 'http://www.wikidata.org/entity/Q7079511'), ('rel', 'http://www.wikidata.org/prop/direct/P4969'), ('name', 'derivative work')]
# [('p', 'http://www.wikidata.org/entity/Q4165246'), ('rel', 'http://www.wikidata.org/prop/direct/P5021'), ('name', 'assessment')]
# [('p', 'http://www.wikidata.org/entity/Q85783379'), ('rel', 'http://www.wikidata.org/prop/direct/P5021'), ('name', 'assessment')]
# [('p', '6009'), ('rel', 'http://www.wikidata.org/prop/direct/P5032'), ('name', 'Filmweb.pl film ID')]
# [('p', 'film1/halloween1'), ('rel', 'http://www.wikidata.org/prop/direct/P5099'), ('name', 'Il mondo dei doppiatori ID')]
# [('p', 'http://www.wikidata.org/entity/Q95008'), ('rel', 'http://www.wikidata.org/prop/direct/P57'), ('name', 'director')]
# [('p', '1978-10-25T00:00:00Z'), ('rel', 'http://www.wikidata.org/prop/direct/P577'), ('name', 'publication date')]
# [('p', '1979-07-06T00:00:00Z'), ('rel', 'http://www.wikidata.org/prop/direct/P577'), ('name', 'publication date')]
# [('p', '1979-08-06T00:00:00Z'), ('rel', 'http://www.wikidata.org/prop/direct/P577'), ('name', 'publication date')]
# [('p', 'halloween-die-nacht-des-grauens'), ('rel', 'http://www.wikidata.org/prop/direct/P5786'), ('name', 'Moviepilot.de film ID')]
# [('p', 'http://www.wikidata.org/entity/Q95008'), ('rel', 'http://www.wikidata.org/prop/direct/P58'), ('name', 'screenwriter')]
# [('p', 'http://www.wikidata.org/entity/Q262102'), ('rel', 'http://www.wikidata.org/prop/direct/P58'), ('name', 'screenwriter')]
# [('p', '4025-190'), ('rel', 'http://www.wikidata.org/prop/direct/P5905'), ('name', 'Comic Vine ID')]
# [('p', 'http://www.wikidata.org/entity/Q80656032'), ('rel', 'http://www.wikidata.org/prop/direct/P5970'), ('name', 'Medierådet rating')]
# [('p', 'film/wd/7132'), ('rel', 'http://www.wikidata.org/prop/direct/P6058'), ('name', 'Larousse ID')]
# [('p', 'halloween-1978'), ('rel', 'http://www.wikidata.org/prop/direct/P6127'), ('name', 'Letterboxd film ID')]
# [('p', 'halloweenmovie:Halloween_(1978)'), ('rel', 'http://www.wikidata.org/prop/direct/P6262'), ('name', 'Fandom article ID')]
# [('p', 'movies:Halloween_(1978)'), ('rel', 'http://www.wikidata.org/prop/direct/P6262'), ('name', 'Fandom article ID')]
# [('p', '1052963015'), ('rel', 'http://www.wikidata.org/prop/direct/P6398'), ('name', 'iTunes movie ID')]
# [('p', '/m/0m3gy'), ('rel', 'http://www.wikidata.org/prop/direct/P646'), ('name', 'Freebase ID')]
# [('p', '1014626'), ('rel', 'http://www.wikidata.org/prop/direct/P7334'), ('name', 'Vudu video ID')]
# [('p', 'http://www.wikidata.org/entity/Q907311'), ('rel', 'http://www.wikidata.org/prop/direct/P750'), ('name', 'distributed by')]
# [('p', 'http://www.wikidata.org/entity/Q3685076'), ('rel', 'http://www.wikidata.org/prop/direct/P750'), ('name', 'distributed by')]
# [('p', 'halloween-m100017116'), ('rel', 'http://www.wikidata.org/prop/direct/P8033'), ('name', 'Movie Review Query Engine ID')]
# [('p', 'http://www.wikidata.org/entity/Q101479794'), ('rel', 'http://www.wikidata.org/prop/direct/P840'), ('name', 'narrative location')]
# [('p', 'http://www.wikidata.org/entity/Q210999'), ('rel', 'http://www.wikidata.org/prop/direct/P8411'), ('name', 'set in environment')]
# [('p', 'http://www.theofficialjohncarpenter.com/pages/themovies/hw/hw.html'), ('rel', 'http://www.wikidata.org/prop/direct/P856'), ('name', 'official website')]
# [('p', 'http://www.wikidata.org/entity/Q95008'), ('rel', 'http://www.wikidata.org/prop/direct/P86'), ('name', 'composer')]
# [('p', '41366'), ('rel', 'http://www.wikidata.org/prop/direct/P905'), ('name', 'PORT film ID')]
# [('p', 'http://www.wikidata.org/entity/Q65'), ('rel', 'http://www.wikidata.org/prop/direct/P915'), ('name', 'filming location')]
# [('p', 'http://www.wikidata.org/entity/Q99'), ('rel', 'http://www.wikidata.org/prop/direct/P915'), ('name', 'filming location')]
# [('p', 'http://www.wikidata.org/entity/Q484188'), ('rel', 'http://www.wikidata.org/prop/direct/P921'), ('name', 'main subject')]
# [('p', 'umc.cmc.3ucmuzhhu97vky5ss9shi57ba'), ('rel', 'http://www.wikidata.org/prop/direct/P9586'), ('name', 'Apple TV movie ID')]
# [('p', 'http://www.wikidata.org/entity/Q574983'), ('rel', 'http://www.wikidata.org/prop/direct/P2554'), ('name', 'production designer')]
# [('p', 'http://www.wikidata.org/entity/Q380471'), ('rel', 'http://www.wikidata.org/prop/direct/P1431'), ('name', 'executive producer')]
# [('p', 'http://www.wikidata.org/entity/Q2483'), ('rel', 'http://www.wikidata.org/prop/direct/P2408'), ('name', 'set in period')]
# [('p', 'http://www.wikidata.org/entity/Q2755'), ('rel', 'http://www.wikidata.org/prop/direct/P2408'), ('name', 'set in period')]
# [('p', '10966'), ('rel', 'http://www.wikidata.org/prop/direct/P4277'), ('name', 'Daum movie ID')]
# [('p', '1077'), ('rel', 'http://www.wikidata.org/prop/direct/P7975'), ('name', 'Filmfront film ID')]
# [('p', 'http://www.wikidata.org/entity/Q251868'), ('rel', 'http://www.wikidata.org/prop/direct/P9215'), ('name', 'set during recurring event')]
# [('p', 'http://www.wikidata.org/entity/Q1314'), ('rel', 'http://www.wikidata.org/prop/direct/P9215'), ('name', 'set during recurring event')]
# 128

# %%
#here i get the new positions: film editor P1040 which i will check only for the film halloween

# %%
#here i select the workers  for the 2 films i check for the working positions found for the films

queryString = """
SELECT DISTINCT ?worker 
WHERE { 
{

#this stands for the actor which where part of the cast of the film (not the serie) Halloween 
wd:Q221103 wdt:P161 ?worker.




}
UNION

{
 
wd:Q221103 wdt:P58 ?worker.
}
UNION

{
 
wd:Q221103 wdt:P57 ?worker.
}
UNION

{
 
wd:Q221103 wdt:P344 ?worker.
}
UNION

{
 
wd:Q221103 wdt:P175 ?worker.
}
UNION

{
 
wd:Q221103 wdt:P162 ?worker.
}
UNION

{
 
wd:Q221103 wdt:P2554 ?worker.
}
UNION

{
 
wd:Q221103 wdt:P86 ?worker.
}
UNION
{
 
wd:Q221103 wdt:P1040 ?worker.
}
#then i get the workers of the second film
UNION
{


#this stands for the actor which where part of the cast of the film (not the serie)  
wd:Q1243029 wdt:P161 ?worker.



}
UNION

{
 
wd:Q1243029 wdt:P58 ?worker.
}
UNION

{
 
wd:Q1243029 wdt:P57 ?worker.
}
UNION

{
 
wd:Q1243029 wdt:P344 ?worker.
}
UNION

{
 
wd:Q1243029 wdt:P175 ?worker.
}
UNION

{
 
wd:Q1243029 wdt:P162 ?worker.
}
UNION

{
 
wd:Q1243029 wdt:P2554 ?worker.
}
UNION

{
 
wd:Q1243029 wdt:P86 ?worker.
}

}

LIMIT 50

"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('worker', 'http://www.wikidata.org/entity/Q2865227')]
# [('worker', 'http://www.wikidata.org/entity/Q3066766')]
# [('worker', 'http://www.wikidata.org/entity/Q106997')]
# [('worker', 'http://www.wikidata.org/entity/Q201570')]
# [('worker', 'http://www.wikidata.org/entity/Q1064022')]
# [('worker', 'http://www.wikidata.org/entity/Q95008')]
# [('worker', 'http://www.wikidata.org/entity/Q936000')]
# [('worker', 'http://www.wikidata.org/entity/Q1853959')]
# [('worker', 'http://www.wikidata.org/entity/Q314914')]
# [('worker', 'http://www.wikidata.org/entity/Q3093664')]
# [('worker', 'http://www.wikidata.org/entity/Q270079')]
# [('worker', 'http://www.wikidata.org/entity/Q6963012')]
# [('worker', 'http://www.wikidata.org/entity/Q6248629')]
# [('worker', 'http://www.wikidata.org/entity/Q262102')]
# [('worker', 'http://www.wikidata.org/entity/Q497036')]
# [('worker', 'http://www.wikidata.org/entity/Q380471')]
# [('worker', 'http://www.wikidata.org/entity/Q3802169')]
# [('worker', 'http://www.wikidata.org/entity/Q574983')]
# [('worker', 'http://www.wikidata.org/entity/Q2440012')]
# [('worker', 'http://www.wikidata.org/entity/Q263765')]
# [('worker', 'http://www.wikidata.org/entity/Q3428829')]
# [('worker', 'http://www.wikidata.org/entity/Q3434272')]
# [('worker', 'http://www.wikidata.org/entity/Q3454165')]
# [('worker', 'http://www.wikidata.org/entity/Q13218111')]
# [('worker', 'http://www.wikidata.org/entity/Q2570201')]
# [('worker', 'http://www.wikidata.org/entity/Q3047636')]
# [('worker', 'http://www.wikidata.org/entity/Q524486')]
# [('worker', 'http://www.wikidata.org/entity/Q7926158')]
# [('worker', 'http://www.wikidata.org/entity/Q709325')]
# [('worker', 'http://www.wikidata.org/entity/Q4863956')]
# [('worker', 'http://www.wikidata.org/entity/Q664025')]
# [('worker', 'http://www.wikidata.org/entity/Q450964')]
# 32

# %%
#here i get the workers who worked in both films (first the workers who where present in alloween then i look if they had a relation in the other film)

queryString = """
SELECT DISTINCT ?worker 
WHERE { 
{

#this stands for the actor which where part of the cast of the film (not the serie) Halloween 
wd:Q221103 wdt:P161 ?worker.




}
UNION

{
 
wd:Q221103 wdt:P58 ?worker.
}
UNION

{
 
wd:Q221103 wdt:P57 ?worker.
}
UNION

{
 
wd:Q221103 wdt:P344 ?worker. 
}
UNION

{
 
wd:Q221103 wdt:P175 ?worker.
}
UNION

{
 
wd:Q221103 wdt:P162 ?worker.
}
UNION

{
 
wd:Q221103 wdt:P2554 ?worker.
}
UNION

{
 
wd:Q221103 wdt:P86 ?worker.
}
UNION
{
 
wd:Q221103 wdt:P1040 ?worker.
}
FILTER EXISTS {wd:Q1243029 ?relation ?worker}.
}

LIMIT 50

"""

print("Results")
run_query(queryString)
# Out:
# Results
# Empty
# 0

# %%
#so i found that there are not workers in common between the two films

# %% [markdown]
# ## Task 2

# %%
#here i investigate all the relationship with an actor found before Adrienne King Q2440012 to get the profession actor
queryString = """
SELECT ?p ?rel ?name
WHERE { 

wd:Q2440012 ?rel ?p.
# ?rel <http://schema.org/name> ?name .
} LIMIT 50
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/entity/Q1028181'), ('rel', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('p', 'http://www.wikidata.org/entity/Q10800557'), ('rel', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('p', 'http://www.wikidata.org/entity/Q2259451'), ('rel', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('p', 'http://www.wikidata.org/entity/Q2405480'), ('rel', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('p', 'http://www.wikidata.org/entity/Q33999'), ('rel', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('p', 'http://www.wikidata.org/entity/Q5716684'), ('rel', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('p', 'http://www.wikidata.org/entity/Q897317'), ('rel', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('p', '1609'), ('rel', 'http://www.wikidata.org/prop/direct/P1266'), ('name', 'AlloCiné person ID')]
# [('p', '80116835'), ('rel', 'http://www.wikidata.org/prop/direct/P1280'), ('name', 'CONOR.SI ID')]
# [('p', 'http://www.wikidata.org/entity/Q1860'), ('rel', 'http://www.wikidata.org/prop/direct/P1412'), ('name', 'languages spoken, written or signed')]
# [('p', 'http://commons.wikimedia.org/wiki/Special:FilePath/Adrienne%20King.jpg'), ('rel', 'http://www.wikidata.org/prop/direct/P18'), ('name', 'image')]
# [('p', 'http://www.wikidata.org/entity/Q18438'), ('rel', 'http://www.wikidata.org/prop/direct/P19'), ('name', 'place of birth')]
# [('p', 'p38252'), ('rel', 'http://www.wikidata.org/prop/direct/P2019'), ('name', 'AllMovie person ID')]
# [('p', '1965-01-01T00:00:00Z'), ('rel', 'http://www.wikidata.org/prop/direct/P2031'), ('name', 'work period (start)')]
# [('p', 'http://www.wikidata.org/entity/Q6581072'), ('rel', 'http://www.wikidata.org/prop/direct/P21'), ('name', 'sex or gender')]
# [('p', '0000 0001 1490 0753'), ('rel', 'http://www.wikidata.org/prop/direct/P213'), ('name', 'ISNI')]
# [('p', '37126862'), ('rel', 'http://www.wikidata.org/prop/direct/P214'), ('name', 'VIAF ID')]
# [('p', '84700'), ('rel', 'http://www.wikidata.org/prop/direct/P2168'), ('name', 'Swedish Film Database person ID')]
# [('p', '237238'), ('rel', 'http://www.wikidata.org/prop/direct/P2387'), ('name', 'Elonet person ID')]
# [('p', 'no2009122943'), ('rel', 'http://www.wikidata.org/prop/direct/P244'), ('name', 'Library of Congress authority ID')]
# [('p', '156447'), ('rel', 'http://www.wikidata.org/prop/direct/P2604'), ('name', 'Kinopoisk person ID')]
# [('p', '10992'), ('rel', 'http://www.wikidata.org/prop/direct/P2605'), ('name', 'ČSFD person ID')]
# [('p', '29469'), ('rel', 'http://www.wikidata.org/prop/direct/P2626'), ('name', 'Danish National Filmography person ID')]
# [('p', '14193593p'), ('rel', 'http://www.wikidata.org/prop/direct/P268'), ('name', 'Bibliothèque nationale de France ID')]
# [('p', '162333978'), ('rel', 'http://www.wikidata.org/prop/direct/P269'), ('name', 'IdRef ID')]
# [('p', 'http://www.wikidata.org/entity/Q30'), ('rel', 'http://www.wikidata.org/prop/direct/P27'), ('name', 'country of citizenship')]
# [('p', 'http://www.wikidata.org/entity/Q5'), ('rel', 'http://www.wikidata.org/prop/direct/P31'), ('name', 'instance of')]
# [('p', 'adrienneking13'), ('rel', 'http://www.wikidata.org/prop/direct/P3265'), ('name', 'Myspace ID')]
# [('p', 'Adrienne-King-1'), ('rel', 'http://www.wikidata.org/prop/direct/P3417'), ('name', 'Quora topic ID')]
# [('p', 'nm0454415'), ('rel', 'http://www.wikidata.org/prop/direct/P345'), ('name', 'IMDb ID')]
# [('p', 'Adrienne King'), ('rel', 'http://www.wikidata.org/prop/direct/P373'), ('name', 'Commons category')]
# [('p', '37470'), ('rel', 'http://www.wikidata.org/prop/direct/P4985'), ('name', 'TMDb person ID')]
# [('p', '41939'), ('rel', 'http://www.wikidata.org/prop/direct/P5033'), ('name', 'Filmweb.pl person ID')]
# [('p', '1955-07-21T00:00:00Z'), ('rel', 'http://www.wikidata.org/prop/direct/P569'), ('name', 'date of birth')]
# [('p', '1960-07-21T00:00:00Z'), ('rel', 'http://www.wikidata.org/prop/direct/P569'), ('name', 'date of birth')]
# [('p', '/m/081vds'), ('rel', 'http://www.wikidata.org/prop/direct/P646'), ('name', 'Freebase ID')]
# [('p', 'http://www.wikidata.org/entity/Q523926'), ('rel', 'http://www.wikidata.org/prop/direct/P69'), ('name', 'educated at')]
# [('p', 'http://www.wikidata.org/entity/Q535214'), ('rel', 'http://www.wikidata.org/prop/direct/P734'), ('name', 'family name')]
# [('p', 'http://www.wikidata.org/entity/Q377369'), ('rel', 'http://www.wikidata.org/prop/direct/P735'), ('name', 'given name')]
# [('p', 'http://www.wikidata.org/entity/Q73555012'), ('rel', 'http://www.wikidata.org/prop/direct/P7763'), ('name', 'copyright status as a creator')]
# [('p', 'lccn-no2009122943'), ('rel', 'http://www.wikidata.org/prop/direct/P7859'), ('name', 'WorldCat Identities ID')]
# [('p', 'http://www.adrienneking.com/'), ('rel', 'http://www.wikidata.org/prop/direct/P856'), ('name', 'official website')]
# [('p', 'XX1473619'), ('rel', 'http://www.wikidata.org/prop/direct/P950'), ('name', 'Biblioteca Nacional de España ID')]
# 43

# %%
#in the query before i get the iri for actor Q33999 and the iri for occupation P106 but i prefer to use cast member so i can identify those who 
#where actually actors in the two films and didn't have another profession

# %%
#i use one actor found before Q3428829 to get the relationship
queryString = """
SELECT ?p ?rel ?name
WHERE { 

wd:Q3454165 ?rel ?p.
# ?rel <http://schema.org/name> ?name .
} LIMIT 50
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('p', '147880998'), ('rel', 'http://www.wikidata.org/prop/direct/P1006'), ('name', 'Nationale Thesaurus voor Auteurs ID')]
# [('p', '98015093'), ('rel', 'http://www.wikidata.org/prop/direct/P1015'), ('name', 'NORAF ID')]
# [('p', 'http://www.wikidata.org/entity/Q10798782'), ('rel', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('p', 'http://www.wikidata.org/entity/Q10800557'), ('rel', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('p', 'http://www.wikidata.org/entity/Q13235160'), ('rel', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('p', 'http://www.wikidata.org/entity/Q2259451'), ('rel', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('p', 'http://www.wikidata.org/entity/Q2405480'), ('rel', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('p', 'http://www.wikidata.org/entity/Q2526255'), ('rel', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('p', 'http://www.wikidata.org/entity/Q3282637'), ('rel', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('p', 'http://www.wikidata.org/entity/Q33999'), ('rel', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('p', 'http://www.wikidata.org/entity/Q3455803'), ('rel', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('p', 'http://www.wikidata.org/entity/Q639669'), ('rel', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('p', 'http://www.wikidata.org/entity/Q948329'), ('rel', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('p', 'n2008131085'), ('rel', 'http://www.wikidata.org/prop/direct/P1207'), ('name', 'NUKAT ID')]
# [('p', '90569'), ('rel', 'http://www.wikidata.org/prop/direct/P1220'), ('name', 'Internet Broadway Database person ID')]
# [('p', '717/000022651'), ('rel', 'http://www.wikidata.org/prop/direct/P1263'), ('name', 'NNDB people ID')]
# [('p', '2130'), ('rel', 'http://www.wikidata.org/prop/direct/P1266'), ('name', 'AlloCiné person ID')]
# [('p', 'http://www.wikidata.org/entity/Q17085462'), ('rel', 'http://www.wikidata.org/prop/direct/P1283'), ('name', 'filmography')]
# [('p', '00000023526'), ('rel', 'http://www.wikidata.org/prop/direct/P1284'), ('name', 'Munzinger person ID')]
# [('p', '1189569'), ('rel', 'http://www.wikidata.org/prop/direct/P1315'), ('name', 'NLA Trove ID')]
# [('p', 'http://www.wikidata.org/entity/Q67311526'), ('rel', 'http://www.wikidata.org/prop/direct/P1343'), ('name', 'described by source')]
# [('p', 'http://www.wikidata.org/entity/Q186472'), ('rel', 'http://www.wikidata.org/prop/direct/P136'), ('name', 'genre')]
# [('p', '000249798'), ('rel', 'http://www.wikidata.org/prop/direct/P1368'), ('name', 'LNB ID')]
# [('p', 'http://www.wikidata.org/entity/Q7066'), ('rel', 'http://www.wikidata.org/prop/direct/P140'), ('name', 'religion')]
# [('p', 'http://www.wikidata.org/entity/Q1860'), ('rel', 'http://www.wikidata.org/prop/direct/P1412'), ('name', 'languages spoken, written or signed')]
# [('p', 'Kevin Norwood Bacon'), ('rel', 'http://www.wikidata.org/prop/direct/P1559'), ('name', 'name in native language')]
# [('p', '00048912'), ('rel', 'http://www.wikidata.org/prop/direct/P1649'), ('name', 'KMDb person ID')]
# [('p', 'http://www.wikidata.org/entity/Q251542'), ('rel', 'http://www.wikidata.org/prop/direct/P166'), ('name', 'award received')]
# [('p', 'http://www.wikidata.org/entity/Q17985761'), ('rel', 'http://www.wikidata.org/prop/direct/P166'), ('name', 'award received')]
# [('p', 'http://www.wikidata.org/entity/Q105447'), ('rel', 'http://www.wikidata.org/prop/direct/P166'), ('name', 'award received')]
# [('p', 'http://www.wikidata.org/entity/Q18600734'), ('rel', 'http://www.wikidata.org/prop/direct/P166'), ('name', 'award received')]
# [('p', 'A1257000X'), ('rel', 'http://www.wikidata.org/prop/direct/P1695'), ('name', 'NLP ID (unique)')]
# [('p', '77838'), ('rel', 'http://www.wikidata.org/prop/direct/P1741'), ('name', 'GTAA ID')]
# [('p', 'http://commons.wikimedia.org/wiki/Special:FilePath/Kevin%20Bacon%20SDCC%202014.jpg'), ('rel', 'http://www.wikidata.org/prop/direct/P18'), ('name', 'image')]
# [('p', 'I00572020'), ('rel', 'http://www.wikidata.org/prop/direct/P1819'), ('name', 'genealogics.org person ID')]
# [('p', 'http://www.wikidata.org/entity/Q1345'), ('rel', 'http://www.wikidata.org/prop/direct/P19'), ('name', 'place of birth')]
# [('p', '956139'), ('rel', 'http://www.wikidata.org/prop/direct/P1953'), ('name', 'Discogs artist ID')]
# [('p', '7338'), ('rel', 'http://www.wikidata.org/prop/direct/P1969'), ('name', 'MovieMeter director ID (former scheme)')]
# [('p', 'kevinbacon'), ('rel', 'http://www.wikidata.org/prop/direct/P2002'), ('name', 'Twitter username')]
# [('p', 'kevinbacon'), ('rel', 'http://www.wikidata.org/prop/direct/P2003'), ('name', 'Instagram username')]
# [('p', 'KevinBacon'), ('rel', 'http://www.wikidata.org/prop/direct/P2013'), ('name', 'Facebook ID')]
# [('p', 'p3164'), ('rel', 'http://www.wikidata.org/prop/direct/P2019'), ('name', 'AllMovie person ID')]
# [('p', '1978-01-01T00:00:00Z'), ('rel', 'http://www.wikidata.org/prop/direct/P2031'), ('name', 'work period (start)')]
# [('p', 'http://www.wikidata.org/entity/Q6581097'), ('rel', 'http://www.wikidata.org/prop/direct/P21'), ('name', 'sex or gender')]
# [('p', '0000 0001 2129 1300'), ('rel', 'http://www.wikidata.org/prop/direct/P213'), ('name', 'ISNI')]
# [('p', '39570812'), ('rel', 'http://www.wikidata.org/prop/direct/P214'), ('name', 'VIAF ID')]
# [('p', '242183'), ('rel', 'http://www.wikidata.org/prop/direct/P2163'), ('name', 'FAST ID')]
# [('p', '73959'), ('rel', 'http://www.wikidata.org/prop/direct/P2168'), ('name', 'Swedish Film Database person ID')]
# [('p', 'http://www.wikidata.org/entity/Q1285964'), ('rel', 'http://www.wikidata.org/prop/direct/P22'), ('name', 'father')]
# [('p', '124109659'), ('rel', 'http://www.wikidata.org/prop/direct/P227'), ('name', 'GND ID')]
# 50

# %%
#att not correct (time) look at the next one 

#i found the IRI award received which is P166
#i can then check the actors of the first films of each series which received more awards who actually where actors in the films
#FILTER(?time<1978).
#?award wdt:P585 ?time.
queryString = """
SELECT ?actor COUNT(?award) 
WHERE { 
{
#this stands for the actor which where part of the cast of the film (not the serie) Halloween 
wd:Q221103 wdt:P161 ?actor.
#this stands for the awards received
# ?actor wdt:P166 ?award.

#?award wdt:P585 ?time.
#FILTER(?time<"1978"^^xsd:date).
}
UNION
{
wd:Q1243029  wdt:P161 ?actor.
# ?actor wdt:P166 ?award.
#?award wdt:P585 ?time.
#FILTER(?time<"1980"^^xsd:date).
}

}GROUP BY(?actor)
LIMIT 50
"""

print("Results")
run_query(queryString)



#anyway none of the actors returned received an academy awards before the movies so i check which one partecipated in more films before the movies
# Out:
# Results
# [('actor', 'http://www.wikidata.org/entity/Q3454165'), ('callret-1', '4')]
# [('actor', 'http://www.wikidata.org/entity/Q314914'), ('callret-1', '1')]
# [('actor', 'http://www.wikidata.org/entity/Q106997'), ('callret-1', '3')]
# 3

# %%
#actor/actress who acted in more movies before here i check for both the films i check for the actor or actress who actually where actors in the films
queryString = """
SELECT ?actor COUNT(?film) as ?number 
WHERE { 
{

#this stands for the actor which where part of the cast of the film (not the serie) Halloween 
wd:Q221103 wdt:P161 ?actor.
# ?film wdt:P161 ?actor.
# ?film wdt:P577 ?date.


FILTER(?date<"1978"^^xsd:date).
}
UNION
{


#this stands for the actor which where part of the cast of the film (not the serie)  
wd:Q1243029 wdt:P161 ?actor.
# ?film wdt:P161 ?actor.
# ?film wdt:P577 ?date.

FILTER(?date<"1980"^^xsd:date).
}
}
GROUP BY(?actor)
ORDER BY DESC(?number)
LIMIT 1

"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('actor', 'http://www.wikidata.org/entity/Q314914'), ('number', '87')]
# 1

# %%
#so the most famous actor (did more films before) was Donald Pleasence

# %% [markdown]
# ## Task 3

# %%
#Check which actor/actress did more movies after the release of these two films (consider the films separately) i consider actors as cast members so i 
#consider only those who where actors in the two films and not those who had another profession in the films
#here i check for the film Halloween
queryString = """
SELECT ?actor COUNT(?film) as ?number 
WHERE { 


#this stands for the actor which where part of the cast of the film (not the serie) Halloween 
wd:Q221103 wdt:P161 ?actor.
# ?film wdt:P161 ?actor.
# ?film wdt:P577 ?date.


FILTER(?date>"1978"^^xsd:date).
}
GROUP BY(?actor)
ORDER BY DESC(?number)
LIMIT 1
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('actor', 'http://www.wikidata.org/entity/Q314914'), ('number', '126')]
# 1

# %%
#Check which actor/actress did more movies after the release of these two films (consider the films separately)
#here i check for the film FRIDAY
queryString = """
SELECT ?actor COUNT(?film) as ?number
WHERE { 


#this stands for the actor which where part of the cast of the film (not the serie)  
wd:Q1243029 wdt:P161 ?actor.
# ?film wdt:P161 ?actor.
# ?film wdt:P577 ?date.

FILTER(?date>"1980"^^xsd:date).

}GROUP BY(?actor)
ORDER BY DESC(?number)
LIMIT 10
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('actor', 'http://www.wikidata.org/entity/Q3454165'), ('number', '110')]
# [('actor', 'http://www.wikidata.org/entity/Q2440012'), ('number', '22')]
# [('actor', 'http://www.wikidata.org/entity/Q263765'), ('number', '13')]
# [('actor', 'http://www.wikidata.org/entity/Q3434272'), ('number', '10')]
# [('actor', 'http://www.wikidata.org/entity/Q3428829'), ('number', '8')]
# [('actor', 'http://www.wikidata.org/entity/Q524486'), ('number', '5')]
# [('actor', 'http://www.wikidata.org/entity/Q3047636'), ('number', '5')]
# [('actor', 'http://www.wikidata.org/entity/Q13218111'), ('number', '3')]
# [('actor', 'http://www.wikidata.org/entity/Q2570201'), ('number', '3')]
# 9

# %% [markdown]
# ## Task 4

# %%
#in the queries before i get the iri Q1138878 whic represent the series friday the 13 and the iri for part of the series  P179
#here i try to get the series halloween
#i investigate the relationship with the film
queryString = """
SELECT ?p ?rel ?name
WHERE { 

wd:Q221103 ?rel ?p.
# ?rel <http://schema.org/name> ?name .
} LIMIT 200
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/entity/Q574983'), ('rel', 'http://www.wikidata.org/prop/direct/P1040'), ('name', 'film editor')]
# [('p', 'halloween'), ('rel', 'http://www.wikidata.org/prop/direct/P1237'), ('name', 'Box Office Mojo film ID (former scheme)')]
# [('p', 'm/1009113-halloween'), ('rel', 'http://www.wikidata.org/prop/direct/P1258'), ('name', 'Rotten Tomatoes ID')]
# [('p', '9434'), ('rel', 'http://www.wikidata.org/prop/direct/P1265'), ('name', 'AlloCiné film ID')]
# [('p', 'http://www.wikidata.org/entity/Q377616'), ('rel', 'http://www.wikidata.org/prop/direct/P135'), ('name', 'movement')]
# [('p', 'http://www.wikidata.org/entity/Q130232'), ('rel', 'http://www.wikidata.org/prop/direct/P136'), ('name', 'genre')]
# [('p', 'http://www.wikidata.org/entity/Q200092'), ('rel', 'http://www.wikidata.org/prop/direct/P136'), ('name', 'genre')]
# [('p', 'http://www.wikidata.org/entity/Q1146335'), ('rel', 'http://www.wikidata.org/prop/direct/P136'), ('name', 'genre')]
# [('p', 'http://www.wikidata.org/entity/Q853630'), ('rel', 'http://www.wikidata.org/prop/direct/P136'), ('name', 'genre')]
# [('p', 'topic/Halloween-1978-film'), ('rel', 'http://www.wikidata.org/prop/direct/P1417'), ('name', 'Encyclopædia Britannica Online ID')]
# [('p', 'http://www.wikidata.org/entity/Q101480110'), ('rel', 'http://www.wikidata.org/prop/direct/P1434'), ('name', 'takes place in fictional universe')]
# [('p', 'Halloween'), ('rel', 'http://www.wikidata.org/prop/direct/P1476'), ('name', 'title')]
# [('p', 'http://www.wikidata.org/entity/Q850312'), ('rel', 'http://www.wikidata.org/prop/direct/P156'), ('name', 'followed by')]
# [('p', 'v21317'), ('rel', 'http://www.wikidata.org/prop/direct/P1562'), ('name', 'AllMovie title ID')]
# [('p', 'http://www.wikidata.org/entity/Q2865227'), ('rel', 'http://www.wikidata.org/prop/direct/P161'), ('name', 'cast member')]
# [('p', 'http://www.wikidata.org/entity/Q3066766'), ('rel', 'http://www.wikidata.org/prop/direct/P161'), ('name', 'cast member')]
# [('p', 'http://www.wikidata.org/entity/Q106997'), ('rel', 'http://www.wikidata.org/prop/direct/P161'), ('name', 'cast member')]
# [('p', 'http://www.wikidata.org/entity/Q201570'), ('rel', 'http://www.wikidata.org/prop/direct/P161'), ('name', 'cast member')]
# [('p', 'http://www.wikidata.org/entity/Q1064022'), ('rel', 'http://www.wikidata.org/prop/direct/P161'), ('name', 'cast member')]
# [('p', 'http://www.wikidata.org/entity/Q95008'), ('rel', 'http://www.wikidata.org/prop/direct/P161'), ('name', 'cast member')]
# [('p', 'http://www.wikidata.org/entity/Q936000'), ('rel', 'http://www.wikidata.org/prop/direct/P161'), ('name', 'cast member')]
# [('p', 'http://www.wikidata.org/entity/Q1853959'), ('rel', 'http://www.wikidata.org/prop/direct/P161'), ('name', 'cast member')]
# [('p', 'http://www.wikidata.org/entity/Q314914'), ('rel', 'http://www.wikidata.org/prop/direct/P161'), ('name', 'cast member')]
# [('p', 'http://www.wikidata.org/entity/Q3093664'), ('rel', 'http://www.wikidata.org/prop/direct/P161'), ('name', 'cast member')]
# [('p', 'http://www.wikidata.org/entity/Q270079'), ('rel', 'http://www.wikidata.org/prop/direct/P161'), ('name', 'cast member')]
# [('p', 'http://www.wikidata.org/entity/Q6963012'), ('rel', 'http://www.wikidata.org/prop/direct/P161'), ('name', 'cast member')]
# [('p', 'http://www.wikidata.org/entity/Q6248629'), ('rel', 'http://www.wikidata.org/prop/direct/P161'), ('name', 'cast member')]
# [('p', 'http://www.wikidata.org/entity/Q262102'), ('rel', 'http://www.wikidata.org/prop/direct/P162'), ('name', 'producer')]
# [('p', 'http://www.wikidata.org/entity/Q380471'), ('rel', 'http://www.wikidata.org/prop/direct/P162'), ('name', 'producer')]
# [('p', 'http://www.wikidata.org/entity/Q3802169'), ('rel', 'http://www.wikidata.org/prop/direct/P162'), ('name', 'producer')]
# [('p', 'http://www.wikidata.org/entity/Q823422'), ('rel', 'http://www.wikidata.org/prop/direct/P166'), ('name', 'award received')]
# [('p', 'movie/halloween-1978'), ('rel', 'http://www.wikidata.org/prop/direct/P1712'), ('name', 'Metacritic ID')]
# [('p', 'http://www.wikidata.org/entity/Q95008'), ('rel', 'http://www.wikidata.org/prop/direct/P175'), ('name', 'performer')]
# [('p', 'http://www.wikidata.org/entity/Q1364022'), ('rel', 'http://www.wikidata.org/prop/direct/P179'), ('name', 'part of the series')]
# [('p', '16863'), ('rel', 'http://www.wikidata.org/prop/direct/P1804'), ('name', 'DNF film ID')]
# [('p', '569090'), ('rel', 'http://www.wikidata.org/prop/direct/P1874'), ('name', 'Netflix ID')]
# [('p', 'http://www.wikidata.org/entity/Q229620'), ('rel', 'http://www.wikidata.org/prop/direct/P1889'), ('name', 'different from')]
# [('p', '1081'), ('rel', 'http://www.wikidata.org/prop/direct/P1970'), ('name', 'MovieMeter film ID')]
# [('p', '91'), ('rel', 'http://www.wikidata.org/prop/direct/P2047'), ('name', 'duration')]
# [('p', 'http://www.wikidata.org/entity/Q21062414'), ('rel', 'http://www.wikidata.org/prop/direct/P2061'), ('name', 'aspect ratio')]
# [('p', '325000'), ('rel', 'http://www.wikidata.org/prop/direct/P2130'), ('name', 'cost')]
# [('p', '183290594'), ('rel', 'http://www.wikidata.org/prop/direct/P214'), ('name', 'VIAF ID')]
# [('p', '7671785-9'), ('rel', 'http://www.wikidata.org/prop/direct/P227'), ('name', 'GND ID')]
# [('p', '8377'), ('rel', 'http://www.wikidata.org/prop/direct/P2334'), ('name', 'Swedish Film Database film ID')]
# [('p', '121090'), ('rel', 'http://www.wikidata.org/prop/direct/P2346'), ('name', 'Elonet movie ID')]
# [('p', 'no98046857'), ('rel', 'http://www.wikidata.org/prop/direct/P244'), ('name', 'Library of Congress authority ID')]
# [('p', '18702'), ('rel', 'http://www.wikidata.org/prop/direct/P2465'), ('name', 'Allcinema film ID')]
# [('p', '7161'), ('rel', 'http://www.wikidata.org/prop/direct/P2508'), ('name', 'KINENOTE film ID')]
# [('p', 'mv7146'), ('rel', 'http://www.wikidata.org/prop/direct/P2509'), ('name', 'Movie Walker film ID')]
# [('p', '2575'), ('rel', 'http://www.wikidata.org/prop/direct/P2518'), ('name', 'Scope.dk film ID')]
# [('p', '1322'), ('rel', 'http://www.wikidata.org/prop/direct/P2529'), ('name', 'ČSFD film ID')]
# [('p', '8435'), ('rel', 'http://www.wikidata.org/prop/direct/P2603'), ('name', 'Kinopoisk film ID')]
# [('p', '77236'), ('rel', 'http://www.wikidata.org/prop/direct/P2631'), ('name', 'TCM Movie Database film ID')]
# [('p', 'movies/halloween'), ('rel', 'http://www.wikidata.org/prop/direct/P2638'), ('name', 'TV.com ID')]
# [('p', '10.5240/F55B-E276-0102-C4C1-93B5-Y'), ('rel', 'http://www.wikidata.org/prop/direct/P2704'), ('name', 'EIDR content ID')]
# [('p', 'http://www.wikidata.org/entity/Q3685076'), ('rel', 'http://www.wikidata.org/prop/direct/P272'), ('name', 'production company')]
# [('p', 'http://www.wikidata.org/entity/Q23830579'), ('rel', 'http://www.wikidata.org/prop/direct/P2747'), ('name', 'Filmiroda rating')]
# [('p', '18105'), ('rel', 'http://www.wikidata.org/prop/direct/P3077'), ('name', 'Cineplex Germany film ID')]
# [('p', 'http://www.wikidata.org/entity/Q11424'), ('rel', 'http://www.wikidata.org/prop/direct/P31'), ('name', 'instance of')]
# [('p', '16452'), ('rel', 'http://www.wikidata.org/prop/direct/P3107'), ('name', 'LdiF ID')]
# [('p', '651007'), ('rel', 'http://www.wikidata.org/prop/direct/P3129'), ('name', 'cine.gr film ID')]
# [('p', '63'), ('rel', 'http://www.wikidata.org/prop/direct/P3138'), ('name', 'OFDb film ID')]
# [('p', 't0003057'), ('rel', 'http://www.wikidata.org/prop/direct/P3141'), ('name', 'EDb film ID')]
# [('p', '77467'), ('rel', 'http://www.wikidata.org/prop/direct/P3143'), ('name', 'elFilm film ID')]
# [('p', '0000-0001-3D3E-0000-E-0000-0000-W'), ('rel', 'http://www.wikidata.org/prop/direct/P3212'), ('name', 'ISAN')]
# [('p', '948'), ('rel', 'http://www.wikidata.org/prop/direct/P3302'), ('name', 'Open Media Database film ID')]
# [('p', 'http://www.wikidata.org/entity/Q497036'), ('rel', 'http://www.wikidata.org/prop/direct/P344'), ('name', 'director of photography')]
# [('p', 'tt0077651'), ('rel', 'http://www.wikidata.org/prop/direct/P345'), ('name', 'IMDb ID')]
# [('p', '56347'), ('rel', 'http://www.wikidata.org/prop/direct/P3593'), ('name', 'AFI Catalog of Feature Films ID')]
# [('p', 'http://www.wikidata.org/entity/Q1860'), ('rel', 'http://www.wikidata.org/prop/direct/P364'), ('name', 'original language of film or TV show')]
# [('p', '125497'), ('rel', 'http://www.wikidata.org/prop/direct/P3804'), ('name', 'TV Guide show ID (former scheme)')]
# [('p', 'Halloween'), ('rel', 'http://www.wikidata.org/prop/direct/P3808'), ('name', 'The Numbers movie ID')]
# [('p', '1392'), ('rel', 'http://www.wikidata.org/prop/direct/P3844'), ('name', 'Deutsche Synchronkartei film ID')]
# [('p', '1331081'), ('rel', 'http://www.wikidata.org/prop/direct/P3933'), ('name', 'Cinema.de ID')]
# [('p', '787'), ('rel', 'http://www.wikidata.org/prop/direct/P4276'), ('name', 'Cinémathèque québécoise work identifier')]
# [('p', '12659'), ('rel', 'http://www.wikidata.org/prop/direct/P4282'), ('name', 'LUMIERE film ID')]
# [('p', 'http://www.wikidata.org/entity/Q723685'), ('rel', 'http://www.wikidata.org/prop/direct/P437'), ('name', 'distribution format')]
# [('p', '1299586'), ('rel', 'http://www.wikidata.org/prop/direct/P4529'), ('name', 'Douban film ID')]
# [('p', 'http://www.wikidata.org/entity/Q22006653'), ('rel', 'http://www.wikidata.org/prop/direct/P462'), ('name', 'color')]
# [('p', '2815'), ('rel', 'http://www.wikidata.org/prop/direct/P4632'), ('name', 'Bechdel Test Movie List ID')]
# [('p', '1774'), ('rel', 'http://www.wikidata.org/prop/direct/P4665'), ('name', 'CineMagia title ID')]
# [('p', '11287'), ('rel', 'http://www.wikidata.org/prop/direct/P4780'), ('name', 'MYmovies movie ID')]
# [('p', '384174'), ('rel', 'http://www.wikidata.org/prop/direct/P480'), ('name', 'FilmAffinity ID')]
# [('p', '948'), ('rel', 'http://www.wikidata.org/prop/direct/P4947'), ('name', 'TMDb movie ID')]
# [('p', 'http://www.wikidata.org/entity/Q30'), ('rel', 'http://www.wikidata.org/prop/direct/P495'), ('name', 'country of origin')]
# [('p', 'http://www.wikidata.org/entity/Q3285065'), ('rel', 'http://www.wikidata.org/prop/direct/P4969'), ('name', 'derivative work')]
# [('p', 'http://www.wikidata.org/entity/Q4502764'), ('rel', 'http://www.wikidata.org/prop/direct/P4969'), ('name', 'derivative work')]
# [('p', 'http://www.wikidata.org/entity/Q7079511'), ('rel', 'http://www.wikidata.org/prop/direct/P4969'), ('name', 'derivative work')]
# [('p', 'http://www.wikidata.org/entity/Q4165246'), ('rel', 'http://www.wikidata.org/prop/direct/P5021'), ('name', 'assessment')]
# [('p', 'http://www.wikidata.org/entity/Q85783379'), ('rel', 'http://www.wikidata.org/prop/direct/P5021'), ('name', 'assessment')]
# [('p', '6009'), ('rel', 'http://www.wikidata.org/prop/direct/P5032'), ('name', 'Filmweb.pl film ID')]
# [('p', 'film1/halloween1'), ('rel', 'http://www.wikidata.org/prop/direct/P5099'), ('name', 'Il mondo dei doppiatori ID')]
# [('p', 'http://www.wikidata.org/entity/Q95008'), ('rel', 'http://www.wikidata.org/prop/direct/P57'), ('name', 'director')]
# [('p', '1978-10-25T00:00:00Z'), ('rel', 'http://www.wikidata.org/prop/direct/P577'), ('name', 'publication date')]
# [('p', '1979-07-06T00:00:00Z'), ('rel', 'http://www.wikidata.org/prop/direct/P577'), ('name', 'publication date')]
# [('p', '1979-08-06T00:00:00Z'), ('rel', 'http://www.wikidata.org/prop/direct/P577'), ('name', 'publication date')]
# [('p', 'halloween-die-nacht-des-grauens'), ('rel', 'http://www.wikidata.org/prop/direct/P5786'), ('name', 'Moviepilot.de film ID')]
# [('p', 'http://www.wikidata.org/entity/Q95008'), ('rel', 'http://www.wikidata.org/prop/direct/P58'), ('name', 'screenwriter')]
# [('p', 'http://www.wikidata.org/entity/Q262102'), ('rel', 'http://www.wikidata.org/prop/direct/P58'), ('name', 'screenwriter')]
# [('p', '4025-190'), ('rel', 'http://www.wikidata.org/prop/direct/P5905'), ('name', 'Comic Vine ID')]
# [('p', 'http://www.wikidata.org/entity/Q80656032'), ('rel', 'http://www.wikidata.org/prop/direct/P5970'), ('name', 'Medierådet rating')]
# [('p', 'film/wd/7132'), ('rel', 'http://www.wikidata.org/prop/direct/P6058'), ('name', 'Larousse ID')]
# [('p', 'halloween-1978'), ('rel', 'http://www.wikidata.org/prop/direct/P6127'), ('name', 'Letterboxd film ID')]
# [('p', 'halloweenmovie:Halloween_(1978)'), ('rel', 'http://www.wikidata.org/prop/direct/P6262'), ('name', 'Fandom article ID')]
# [('p', 'movies:Halloween_(1978)'), ('rel', 'http://www.wikidata.org/prop/direct/P6262'), ('name', 'Fandom article ID')]
# [('p', '1052963015'), ('rel', 'http://www.wikidata.org/prop/direct/P6398'), ('name', 'iTunes movie ID')]
# [('p', '/m/0m3gy'), ('rel', 'http://www.wikidata.org/prop/direct/P646'), ('name', 'Freebase ID')]
# [('p', '1014626'), ('rel', 'http://www.wikidata.org/prop/direct/P7334'), ('name', 'Vudu video ID')]
# [('p', 'http://www.wikidata.org/entity/Q907311'), ('rel', 'http://www.wikidata.org/prop/direct/P750'), ('name', 'distributed by')]
# [('p', 'http://www.wikidata.org/entity/Q3685076'), ('rel', 'http://www.wikidata.org/prop/direct/P750'), ('name', 'distributed by')]
# [('p', 'halloween-m100017116'), ('rel', 'http://www.wikidata.org/prop/direct/P8033'), ('name', 'Movie Review Query Engine ID')]
# [('p', 'http://www.wikidata.org/entity/Q101479794'), ('rel', 'http://www.wikidata.org/prop/direct/P840'), ('name', 'narrative location')]
# [('p', 'http://www.wikidata.org/entity/Q210999'), ('rel', 'http://www.wikidata.org/prop/direct/P8411'), ('name', 'set in environment')]
# [('p', 'http://www.theofficialjohncarpenter.com/pages/themovies/hw/hw.html'), ('rel', 'http://www.wikidata.org/prop/direct/P856'), ('name', 'official website')]
# [('p', 'http://www.wikidata.org/entity/Q95008'), ('rel', 'http://www.wikidata.org/prop/direct/P86'), ('name', 'composer')]
# [('p', '41366'), ('rel', 'http://www.wikidata.org/prop/direct/P905'), ('name', 'PORT film ID')]
# [('p', 'http://www.wikidata.org/entity/Q65'), ('rel', 'http://www.wikidata.org/prop/direct/P915'), ('name', 'filming location')]
# [('p', 'http://www.wikidata.org/entity/Q99'), ('rel', 'http://www.wikidata.org/prop/direct/P915'), ('name', 'filming location')]
# [('p', 'http://www.wikidata.org/entity/Q484188'), ('rel', 'http://www.wikidata.org/prop/direct/P921'), ('name', 'main subject')]
# [('p', 'umc.cmc.3ucmuzhhu97vky5ss9shi57ba'), ('rel', 'http://www.wikidata.org/prop/direct/P9586'), ('name', 'Apple TV movie ID')]
# [('p', 'http://www.wikidata.org/entity/Q574983'), ('rel', 'http://www.wikidata.org/prop/direct/P2554'), ('name', 'production designer')]
# [('p', 'http://www.wikidata.org/entity/Q380471'), ('rel', 'http://www.wikidata.org/prop/direct/P1431'), ('name', 'executive producer')]
# [('p', 'http://www.wikidata.org/entity/Q2483'), ('rel', 'http://www.wikidata.org/prop/direct/P2408'), ('name', 'set in period')]
# [('p', 'http://www.wikidata.org/entity/Q2755'), ('rel', 'http://www.wikidata.org/prop/direct/P2408'), ('name', 'set in period')]
# [('p', '10966'), ('rel', 'http://www.wikidata.org/prop/direct/P4277'), ('name', 'Daum movie ID')]
# [('p', '1077'), ('rel', 'http://www.wikidata.org/prop/direct/P7975'), ('name', 'Filmfront film ID')]
# [('p', 'http://www.wikidata.org/entity/Q251868'), ('rel', 'http://www.wikidata.org/prop/direct/P9215'), ('name', 'set during recurring event')]
# [('p', 'http://www.wikidata.org/entity/Q1314'), ('rel', 'http://www.wikidata.org/prop/direct/P9215'), ('name', 'set during recurring event')]
# 128

# %%
#P577 forud before is the iri for pubblication date
#in the query before i get the iri for the series halloween Q1364022
#Get all the movies of the two franchises (return year and director)
queryString = """
SELECT DISTINCT ?year ?director ?film
WHERE { 
{
#this are the films part of the Halloween franciase
# ?film wdt:P179 wd:Q1364022.
# ?film wdt:P57 ?director.
# ?film wdt:P577 ?year.
}
UNION
{
# ?film wdt:P179 wd:Q1138878.
# ?film wdt:P57 ?director.
# ?film wdt:P577 ?year.

}

}
LIMIT 50
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('year', '1979-07-06T00:00:00Z'), ('director', 'http://www.wikidata.org/entity/Q95008'), ('film', 'http://www.wikidata.org/entity/Q221103')]
# [('year', '1978-10-25T00:00:00Z'), ('director', 'http://www.wikidata.org/entity/Q95008'), ('film', 'http://www.wikidata.org/entity/Q221103')]
# [('year', '1979-08-06T00:00:00Z'), ('director', 'http://www.wikidata.org/entity/Q95008'), ('film', 'http://www.wikidata.org/entity/Q221103')]
# [('year', '1998-01-01T00:00:00Z'), ('director', 'http://www.wikidata.org/entity/Q107404'), ('film', 'http://www.wikidata.org/entity/Q1050815')]
# [('year', '1998-10-29T00:00:00Z'), ('director', 'http://www.wikidata.org/entity/Q107404'), ('film', 'http://www.wikidata.org/entity/Q1050815')]
# [('year', '2002-01-01T00:00:00Z'), ('director', 'http://www.wikidata.org/entity/Q1384404'), ('film', 'http://www.wikidata.org/entity/Q176488')]
# [('year', '2002-11-07T00:00:00Z'), ('director', 'http://www.wikidata.org/entity/Q1384404'), ('film', 'http://www.wikidata.org/entity/Q176488')]
# [('year', '2007-01-01T00:00:00Z'), ('director', 'http://www.wikidata.org/entity/Q298255'), ('film', 'http://www.wikidata.org/entity/Q909063')]
# [('year', '2007-10-25T00:00:00Z'), ('director', 'http://www.wikidata.org/entity/Q298255'), ('film', 'http://www.wikidata.org/entity/Q909063')]
# [('year', '1981-01-01T00:00:00Z'), ('director', 'http://www.wikidata.org/entity/Q95008'), ('film', 'http://www.wikidata.org/entity/Q850312')]
# [('year', '1981-01-01T00:00:00Z'), ('director', 'http://www.wikidata.org/entity/Q1384404'), ('film', 'http://www.wikidata.org/entity/Q850312')]
# [('year', '1982-11-11T00:00:00Z'), ('director', 'http://www.wikidata.org/entity/Q95008'), ('film', 'http://www.wikidata.org/entity/Q850312')]
# [('year', '1982-11-11T00:00:00Z'), ('director', 'http://www.wikidata.org/entity/Q1384404'), ('film', 'http://www.wikidata.org/entity/Q850312')]
# [('year', '1982-01-01T00:00:00Z'), ('director', 'http://www.wikidata.org/entity/Q574983'), ('film', 'http://www.wikidata.org/entity/Q203705')]
# [('year', '1988-01-01T00:00:00Z'), ('director', 'http://www.wikidata.org/entity/Q1268483'), ('film', 'http://www.wikidata.org/entity/Q959853')]
# [('year', '1989-05-18T00:00:00Z'), ('director', 'http://www.wikidata.org/entity/Q1268483'), ('film', 'http://www.wikidata.org/entity/Q959853')]
# [('year', '1991-07-11T00:00:00Z'), ('director', 'http://www.wikidata.org/entity/Q117234'), ('film', 'http://www.wikidata.org/entity/Q976728')]
# [('year', '1989-01-01T00:00:00Z'), ('director', 'http://www.wikidata.org/entity/Q117234'), ('film', 'http://www.wikidata.org/entity/Q976728')]
# [('year', '2009-01-01T00:00:00Z'), ('director', 'http://www.wikidata.org/entity/Q298255'), ('film', 'http://www.wikidata.org/entity/Q908690')]
# [('year', '2009-10-15T00:00:00Z'), ('director', 'http://www.wikidata.org/entity/Q298255'), ('film', 'http://www.wikidata.org/entity/Q908690')]
# [('year', '1995-01-01T00:00:00Z'), ('director', 'http://www.wikidata.org/entity/Q1381885'), ('film', 'http://www.wikidata.org/entity/Q1138055')]
# [('year', '1981-11-02T00:00:00Z'), ('director', 'http://www.wikidata.org/entity/Q709325'), ('film', 'http://www.wikidata.org/entity/Q1243009')]
# [('year', '1981-11-02T00:00:00Z'), ('director', 'http://www.wikidata.org/entity/Q107404'), ('film', 'http://www.wikidata.org/entity/Q1243009')]
# [('year', '1981-04-30T00:00:00Z'), ('director', 'http://www.wikidata.org/entity/Q709325'), ('film', 'http://www.wikidata.org/entity/Q1243009')]
# [('year', '1981-04-30T00:00:00Z'), ('director', 'http://www.wikidata.org/entity/Q107404'), ('film', 'http://www.wikidata.org/entity/Q1243009')]
# [('year', '1983-05-12T00:00:00Z'), ('director', 'http://www.wikidata.org/entity/Q107404'), ('film', 'http://www.wikidata.org/entity/Q1243013')]
# [('year', '1982-08-13T00:00:00Z'), ('director', 'http://www.wikidata.org/entity/Q107404'), ('film', 'http://www.wikidata.org/entity/Q1243013')]
# [('year', '1983-05-13T00:00:00Z'), ('director', 'http://www.wikidata.org/entity/Q107404'), ('film', 'http://www.wikidata.org/entity/Q1243013')]
# [('year', '1980-11-10T00:00:00Z'), ('director', 'http://www.wikidata.org/entity/Q709325'), ('film', 'http://www.wikidata.org/entity/Q1243029')]
# [('year', '1980-05-09T00:00:00Z'), ('director', 'http://www.wikidata.org/entity/Q709325'), ('film', 'http://www.wikidata.org/entity/Q1243029')]
# [('year', '1980-10-23T00:00:00Z'), ('director', 'http://www.wikidata.org/entity/Q709325'), ('film', 'http://www.wikidata.org/entity/Q1243029')]
# [('year', '2001-01-01T00:00:00Z'), ('director', 'http://www.wikidata.org/entity/Q472868'), ('film', 'http://www.wikidata.org/entity/Q1427521')]
# [('year', '1993-01-01T00:00:00Z'), ('director', 'http://www.wikidata.org/entity/Q4679450'), ('film', 'http://www.wikidata.org/entity/Q1683918')]
# [('year', '1989-01-01T00:00:00Z'), ('director', 'http://www.wikidata.org/entity/Q21280751'), ('film', 'http://www.wikidata.org/entity/Q1454794')]
# [('year', '1988-01-01T00:00:00Z'), ('director', 'http://www.wikidata.org/entity/Q3052099'), ('film', 'http://www.wikidata.org/entity/Q1454798')]
# [('year', '1986-01-01T00:00:00Z'), ('director', 'http://www.wikidata.org/entity/Q730985'), ('film', 'http://www.wikidata.org/entity/Q1454799')]
# [('year', '1985-01-01T00:00:00Z'), ('director', 'http://www.wikidata.org/entity/Q1778633'), ('film', 'http://www.wikidata.org/entity/Q286830')]
# [('year', '1987-01-02T00:00:00Z'), ('director', 'http://www.wikidata.org/entity/Q1778633'), ('film', 'http://www.wikidata.org/entity/Q286830')]
# [('year', '2003-11-20T00:00:00Z'), ('director', 'http://www.wikidata.org/entity/Q525109'), ('film', 'http://www.wikidata.org/entity/Q965859')]
# [('year', '2003-08-13T00:00:00Z'), ('director', 'http://www.wikidata.org/entity/Q525109'), ('film', 'http://www.wikidata.org/entity/Q965859')]
# [('year', '1984-01-01T00:00:00Z'), ('director', 'http://www.wikidata.org/entity/Q11335'), ('film', 'http://www.wikidata.org/entity/Q1243019')]
# [('year', '1984-07-13T00:00:00Z'), ('director', 'http://www.wikidata.org/entity/Q11335'), ('film', 'http://www.wikidata.org/entity/Q1243019')]
# [('year', '2009-01-01T00:00:00Z'), ('director', 'http://www.wikidata.org/entity/Q77399'), ('film', 'http://www.wikidata.org/entity/Q1454815')]
# [('year', '2009-02-13T00:00:00Z'), ('director', 'http://www.wikidata.org/entity/Q77399'), ('film', 'http://www.wikidata.org/entity/Q1454815')]
# 44

# %% [markdown]
# ## Task 5

# %%
#Who is most involved in a franchise (who did something in the movies, e.g., writer, director, producer)?
#here i return the number of apparition for the alloween franciaise for each worker
queryString = """
SELECT  COUNT(?film) as ?apparition ?worker
WHERE { 

#this are the films part of the Halloween franciase
# ?film wdt:P179 wd:Q1364022.

{

#this stands for the actor which where part of the cast of the film 
# ?film wdt:P161 ?worker.




}
UNION

{
 
# ?film wdt:P58 ?worker.
}
UNION

{
 
# ?film wdt:P57 ?worker.
}
UNION

{
 
# ?film wdt:P344 ?worker.
}
UNION

{
 
# ?film wdt:P175 ?worker.
}
UNION

{
 
# ?film wdt:P162 ?worker.
}
UNION

{
 
# ?film wdt:P2554 ?worker.
}
UNION

{
 
# ?film wdt:P86 ?worker.
}
UNION
{
 
# ?film wdt:P1040 ?worker.
}

}GROUP BY (?worker)
ORDER BY DESC(?apparition)
LIMIT 50
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('apparition', '13'), ('worker', 'http://www.wikidata.org/entity/Q95008')]
# [('apparition', '6'), ('worker', 'http://www.wikidata.org/entity/Q262102')]
# [('apparition', '6'), ('worker', 'http://www.wikidata.org/entity/Q298255')]
# [('apparition', '5'), ('worker', 'http://www.wikidata.org/entity/Q314914')]
# [('apparition', '5'), ('worker', 'http://www.wikidata.org/entity/Q106997')]
# [('apparition', '5'), ('worker', 'http://www.wikidata.org/entity/Q574983')]
# [('apparition', '4'), ('worker', 'http://www.wikidata.org/entity/Q730362')]
# [('apparition', '4'), ('worker', 'http://www.wikidata.org/entity/Q272944')]
# [('apparition', '4'), ('worker', 'http://www.wikidata.org/entity/Q380471')]
# [('apparition', '3'), ('worker', 'http://www.wikidata.org/entity/Q497036')]
# [('apparition', '3'), ('worker', 'http://www.wikidata.org/entity/Q1378684')]
# [('apparition', '3'), ('worker', 'http://www.wikidata.org/entity/Q201570')]
# [('apparition', '3'), ('worker', 'http://www.wikidata.org/entity/Q6963012')]
# [('apparition', '3'), ('worker', 'http://www.wikidata.org/entity/Q1384404')]
# [('apparition', '2'), ('worker', 'http://www.wikidata.org/entity/Q3066766')]
# [('apparition', '2'), ('worker', 'http://www.wikidata.org/entity/Q1853959')]
# [('apparition', '2'), ('worker', 'http://www.wikidata.org/entity/Q2329915')]
# [('apparition', '2'), ('worker', 'http://www.wikidata.org/entity/Q6173666')]
# [('apparition', '2'), ('worker', 'http://www.wikidata.org/entity/Q2779609')]
# [('apparition', '2'), ('worker', 'http://www.wikidata.org/entity/Q1345338')]
# [('apparition', '2'), ('worker', 'http://www.wikidata.org/entity/Q329734')]
# [('apparition', '2'), ('worker', 'http://www.wikidata.org/entity/Q449520')]
# [('apparition', '2'), ('worker', 'http://www.wikidata.org/entity/Q117234')]
# [('apparition', '2'), ('worker', 'http://www.wikidata.org/entity/Q117392')]
# [('apparition', '2'), ('worker', 'http://www.wikidata.org/entity/Q374239')]
# [('apparition', '2'), ('worker', 'http://www.wikidata.org/entity/Q552031')]
# [('apparition', '2'), ('worker', 'http://www.wikidata.org/entity/Q107404')]
# [('apparition', '2'), ('worker', 'http://www.wikidata.org/entity/Q238121')]
# [('apparition', '2'), ('worker', 'http://www.wikidata.org/entity/Q1064022')]
# [('apparition', '2'), ('worker', 'http://www.wikidata.org/entity/Q239382')]
# [('apparition', '2'), ('worker', 'http://www.wikidata.org/entity/Q813336')]
# [('apparition', '1'), ('worker', 'http://www.wikidata.org/entity/Q936000')]
# [('apparition', '1'), ('worker', 'http://www.wikidata.org/entity/Q6248629')]
# [('apparition', '1'), ('worker', 'http://www.wikidata.org/entity/Q52440')]
# [('apparition', '1'), ('worker', 'http://www.wikidata.org/entity/Q235677')]
# [('apparition', '1'), ('worker', 'http://www.wikidata.org/entity/Q256884')]
# [('apparition', '1'), ('worker', 'http://www.wikidata.org/entity/Q564851')]
# [('apparition', '1'), ('worker', 'http://www.wikidata.org/entity/Q3048468')]
# [('apparition', '1'), ('worker', 'http://www.wikidata.org/entity/Q3929818')]
# [('apparition', '1'), ('worker', 'http://www.wikidata.org/entity/Q959750')]
# [('apparition', '1'), ('worker', 'http://www.wikidata.org/entity/Q2865227')]
# [('apparition', '1'), ('worker', 'http://www.wikidata.org/entity/Q340213')]
# [('apparition', '1'), ('worker', 'http://www.wikidata.org/entity/Q3453826')]
# [('apparition', '1'), ('worker', 'http://www.wikidata.org/entity/Q350255')]
# [('apparition', '1'), ('worker', 'http://www.wikidata.org/entity/Q703809')]
# [('apparition', '1'), ('worker', 'http://www.wikidata.org/entity/Q2048649')]
# [('apparition', '1'), ('worker', 'http://www.wikidata.org/entity/Q1366623')]
# [('apparition', '1'), ('worker', 'http://www.wikidata.org/entity/Q234471')]
# [('apparition', '1'), ('worker', 'http://www.wikidata.org/entity/Q3296147')]
# [('apparition', '1'), ('worker', 'http://www.wikidata.org/entity/Q5356821')]
# 50

# %%
#Who is most involved in a franchise (who did something in the movies, e.g., writer, director, producer)?
#here i return the number of apparition for the  Friday franciase for each worker
queryString = """
SELECT  COUNT(?film) as ?apparition ?worker
WHERE { 

#this are the films part of the Friday franciase
# ?film wdt:P179 wd:Q1138878.

{

#this stands for the actor which where part of the cast of the film 
# ?film wdt:P161 ?worker.




}
UNION

{
 
# ?film wdt:P58 ?worker.
}
UNION

{
 
# ?film wdt:P57 ?worker.
}
UNION

{
 
# ?film wdt:P344 ?worker.
}
UNION

{
 
# ?film wdt:P175 ?worker.
}
UNION

{
 
# ?film wdt:P162 ?worker.
}
UNION

{
 
# ?film wdt:P2554 ?worker.
}
UNION

{
 
# ?film wdt:P86 ?worker.
}
UNION
{
 
# ?film wdt:P1040 ?worker.
}

}GROUP BY (?worker)
ORDER BY DESC(?apparition)
LIMIT 50
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('apparition', '15'), ('worker', 'http://www.wikidata.org/entity/Q664025')]
# [('apparition', '7'), ('worker', 'http://www.wikidata.org/entity/Q709325')]
# [('apparition', '4'), ('worker', 'http://www.wikidata.org/entity/Q107404')]
# [('apparition', '4'), ('worker', 'http://www.wikidata.org/entity/Q3082711')]
# [('apparition', '4'), ('worker', 'http://www.wikidata.org/entity/Q465134')]
# [('apparition', '3'), ('worker', 'http://www.wikidata.org/entity/Q375419')]
# [('apparition', '3'), ('worker', 'http://www.wikidata.org/entity/Q263765')]
# [('apparition', '2'), ('worker', 'http://www.wikidata.org/entity/Q3116155')]
# [('apparition', '2'), ('worker', 'http://www.wikidata.org/entity/Q1314250')]
# [('apparition', '2'), ('worker', 'http://www.wikidata.org/entity/Q30327831')]
# [('apparition', '2'), ('worker', 'http://www.wikidata.org/entity/Q2440012')]
# [('apparition', '2'), ('worker', 'http://www.wikidata.org/entity/Q6394602')]
# [('apparition', '2'), ('worker', 'http://www.wikidata.org/entity/Q730985')]
# [('apparition', '2'), ('worker', 'http://www.wikidata.org/entity/Q3434272')]
# [('apparition', '2'), ('worker', 'http://www.wikidata.org/entity/Q455879')]
# [('apparition', '2'), ('worker', 'http://www.wikidata.org/entity/Q6234410')]
# [('apparition', '2'), ('worker', 'http://www.wikidata.org/entity/Q450964')]
# [('apparition', '2'), ('worker', 'http://www.wikidata.org/entity/Q3086901')]
# [('apparition', '2'), ('worker', 'http://www.wikidata.org/entity/Q3063036')]
# [('apparition', '2'), ('worker', 'http://www.wikidata.org/entity/Q991651')]
# [('apparition', '2'), ('worker', 'http://www.wikidata.org/entity/Q5246313')]
# [('apparition', '2'), ('worker', 'http://www.wikidata.org/entity/Q1228672')]
# [('apparition', '2'), ('worker', 'http://www.wikidata.org/entity/Q21280751')]
# [('apparition', '2'), ('worker', 'http://www.wikidata.org/entity/Q3428829')]
# [('apparition', '2'), ('worker', 'http://www.wikidata.org/entity/Q4679450')]
# [('apparition', '1'), ('worker', 'http://www.wikidata.org/entity/Q11770584')]
# [('apparition', '1'), ('worker', 'http://www.wikidata.org/entity/Q7626409')]
# [('apparition', '1'), ('worker', 'http://www.wikidata.org/entity/Q55422')]
# [('apparition', '1'), ('worker', 'http://www.wikidata.org/entity/Q1589252')]
# [('apparition', '1'), ('worker', 'http://www.wikidata.org/entity/Q3183440')]
# [('apparition', '1'), ('worker', 'http://www.wikidata.org/entity/Q465914')]
# [('apparition', '1'), ('worker', 'http://www.wikidata.org/entity/Q684370')]
# [('apparition', '1'), ('worker', 'http://www.wikidata.org/entity/Q3038793')]
# [('apparition', '1'), ('worker', 'http://www.wikidata.org/entity/Q231116')]
# [('apparition', '1'), ('worker', 'http://www.wikidata.org/entity/Q3505578')]
# [('apparition', '1'), ('worker', 'http://www.wikidata.org/entity/Q434014')]
# [('apparition', '1'), ('worker', 'http://www.wikidata.org/entity/Q6308992')]
# [('apparition', '1'), ('worker', 'http://www.wikidata.org/entity/Q184249')]
# [('apparition', '1'), ('worker', 'http://www.wikidata.org/entity/Q422310')]
# [('apparition', '1'), ('worker', 'http://www.wikidata.org/entity/Q923279')]
# [('apparition', '1'), ('worker', 'http://www.wikidata.org/entity/Q957454')]
# [('apparition', '1'), ('worker', 'http://www.wikidata.org/entity/Q108006600')]
# [('apparition', '1'), ('worker', 'http://www.wikidata.org/entity/Q108033009')]
# [('apparition', '1'), ('worker', 'http://www.wikidata.org/entity/Q3288389')]
# [('apparition', '1'), ('worker', 'http://www.wikidata.org/entity/Q3454165')]
# [('apparition', '1'), ('worker', 'http://www.wikidata.org/entity/Q13218111')]
# [('apparition', '1'), ('worker', 'http://www.wikidata.org/entity/Q637974')]
# [('apparition', '1'), ('worker', 'http://www.wikidata.org/entity/Q264377')]
# [('apparition', '1'), ('worker', 'http://www.wikidata.org/entity/Q626553')]
# [('apparition', '1'), ('worker', 'http://www.wikidata.org/entity/Q2443799')]
# 50

# %% [markdown]
# ## Task 6

# %%
#SBAGLIATA NON GUARDARE
#i found in the previous query P1712 which is the id for metacritic
#Investigate which franchise is highly regarded by the critics overall
#in this query i return for each film his metacritic ranking
queryString = """
SELECT DISTINCT  ?film ?critic
WHERE { 
{
#this are the films part of the Halloween franciase
# ?film wdt:P179 wd:Q1364022.
# ?film wdt:P444 ?critic.
}
UNION
{
# ?film wdt:P179 wd:Q1138878.
# ?film wdt:P444 ?critic.

}

}
LIMIT 50
"""

print("Results")
run_query(queryString)
# Out:
# Results
# Empty
# 0

# %%
#i already found all the relationship for the film halloween in the previous queries (the first one) so i try alloween 5

# %% [markdown]
# ## Task 7

# %%
#i investigate the relationship with the film Halloween 5 found before
queryString = """
SELECT ?p ?rel ?name
WHERE { 

wd:Q976728 ?rel ?p.
# ?rel <http://schema.org/name> ?name .
} LIMIT 200
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('p', 'halloween5'), ('rel', 'http://www.wikidata.org/prop/direct/P1237'), ('name', 'Box Office Mojo film ID (former scheme)')]
# [('p', 'm/halloween_5_the_revenge_of_michael_myers'), ('rel', 'http://www.wikidata.org/prop/direct/P1258'), ('name', 'Rotten Tomatoes ID')]
# [('p', '57785'), ('rel', 'http://www.wikidata.org/prop/direct/P1265'), ('name', 'AlloCiné film ID')]
# [('p', 'http://www.wikidata.org/entity/Q200092'), ('rel', 'http://www.wikidata.org/prop/direct/P136'), ('name', 'genre')]
# [('p', 'http://www.wikidata.org/entity/Q853630'), ('rel', 'http://www.wikidata.org/prop/direct/P136'), ('name', 'genre')]
# [('p', 'Halloween 5: The Revenge of Michael Myers'), ('rel', 'http://www.wikidata.org/prop/direct/P1476'), ('name', 'title')]
# [('p', 'http://www.wikidata.org/entity/Q959853'), ('rel', 'http://www.wikidata.org/prop/direct/P155'), ('name', 'follows')]
# [('p', 'http://www.wikidata.org/entity/Q27834579'), ('rel', 'http://www.wikidata.org/prop/direct/P1552'), ('name', 'has quality')]
# [('p', 'http://www.wikidata.org/entity/Q27847754'), ('rel', 'http://www.wikidata.org/prop/direct/P1552'), ('name', 'has quality')]
# [('p', 'http://www.wikidata.org/entity/Q1138055'), ('rel', 'http://www.wikidata.org/prop/direct/P156'), ('name', 'followed by')]
# [('p', 'v21321'), ('rel', 'http://www.wikidata.org/prop/direct/P1562'), ('name', 'AllMovie title ID')]
# [('p', 'http://www.wikidata.org/entity/Q813336'), ('rel', 'http://www.wikidata.org/prop/direct/P161'), ('name', 'cast member')]
# [('p', 'http://www.wikidata.org/entity/Q204395'), ('rel', 'http://www.wikidata.org/prop/direct/P161'), ('name', 'cast member')]
# [('p', 'http://www.wikidata.org/entity/Q556064'), ('rel', 'http://www.wikidata.org/prop/direct/P161'), ('name', 'cast member')]
# [('p', 'http://www.wikidata.org/entity/Q743045'), ('rel', 'http://www.wikidata.org/prop/direct/P161'), ('name', 'cast member')]
# [('p', 'http://www.wikidata.org/entity/Q314914'), ('rel', 'http://www.wikidata.org/prop/direct/P161'), ('name', 'cast member')]
# [('p', 'http://www.wikidata.org/entity/Q272944'), ('rel', 'http://www.wikidata.org/prop/direct/P161'), ('name', 'cast member')]
# [('p', 'http://www.wikidata.org/entity/Q2633389'), ('rel', 'http://www.wikidata.org/prop/direct/P161'), ('name', 'cast member')]
# [('p', 'http://www.wikidata.org/entity/Q23900757'), ('rel', 'http://www.wikidata.org/prop/direct/P161'), ('name', 'cast member')]
# [('p', 'http://www.wikidata.org/entity/Q449520'), ('rel', 'http://www.wikidata.org/prop/direct/P161'), ('name', 'cast member')]
# [('p', 'http://www.wikidata.org/entity/Q7982682'), ('rel', 'http://www.wikidata.org/prop/direct/P161'), ('name', 'cast member')]
# [('p', 'http://www.wikidata.org/entity/Q3514655'), ('rel', 'http://www.wikidata.org/prop/direct/P161'), ('name', 'cast member')]
# [('p', 'http://www.wikidata.org/entity/Q380471'), ('rel', 'http://www.wikidata.org/prop/direct/P162'), ('name', 'producer')]
# [('p', 'movie/halloween-5-the-revenge-of-michael-myers'), ('rel', 'http://www.wikidata.org/prop/direct/P1712'), ('name', 'Metacritic ID')]
# [('p', 'http://www.wikidata.org/entity/Q1364022'), ('rel', 'http://www.wikidata.org/prop/direct/P179'), ('name', 'part of the series')]
# [('p', 'http://commons.wikimedia.org/wiki/Special:FilePath/Halloween5bann.jpg'), ('rel', 'http://www.wikidata.org/prop/direct/P18'), ('name', 'image')]
# [('p', '60002050'), ('rel', 'http://www.wikidata.org/prop/direct/P1874'), ('name', 'Netflix ID')]
# [('p', '3859'), ('rel', 'http://www.wikidata.org/prop/direct/P1970'), ('name', 'MovieMeter film ID')]
# [('p', 'http://www.wikidata.org/entity/Q20644797'), ('rel', 'http://www.wikidata.org/prop/direct/P1981'), ('name', 'FSK film rating')]
# [('p', '96'), ('rel', 'http://www.wikidata.org/prop/direct/P2047'), ('name', 'duration')]
# [('p', '11642254'), ('rel', 'http://www.wikidata.org/prop/direct/P2142'), ('name', 'box office')]
# [('p', '37996'), ('rel', 'http://www.wikidata.org/prop/direct/P2334'), ('name', 'Swedish Film Database film ID')]
# [('p', '840694'), ('rel', 'http://www.wikidata.org/prop/direct/P2346'), ('name', 'Elonet movie ID')]
# [('p', '18706'), ('rel', 'http://www.wikidata.org/prop/direct/P2465'), ('name', 'Allcinema film ID')]
# [('p', '46146'), ('rel', 'http://www.wikidata.org/prop/direct/P2508'), ('name', 'KINENOTE film ID')]
# [('p', '5046'), ('rel', 'http://www.wikidata.org/prop/direct/P2518'), ('name', 'Scope.dk film ID')]
# [('p', '7072'), ('rel', 'http://www.wikidata.org/prop/direct/P2529'), ('name', 'ČSFD film ID')]
# [('p', '14501'), ('rel', 'http://www.wikidata.org/prop/direct/P2603'), ('name', 'Kinopoisk film ID')]
# [('p', '77240'), ('rel', 'http://www.wikidata.org/prop/direct/P2631'), ('name', 'TCM Movie Database film ID')]
# [('p', 'movies/halloween-5-the-revenge-of-michael-myers'), ('rel', 'http://www.wikidata.org/prop/direct/P2638'), ('name', 'TV.com ID')]
# [('p', '10.5240/2EB7-ECD2-79CF-5931-E06B-O'), ('rel', 'http://www.wikidata.org/prop/direct/P2704'), ('name', 'EIDR content ID')]
# [('p', '3000000'), ('rel', 'http://www.wikidata.org/prop/direct/P2769'), ('name', 'budget')]
# [('p', 'http://www.wikidata.org/entity/Q11424'), ('rel', 'http://www.wikidata.org/prop/direct/P31'), ('name', 'instance of')]
# [('p', '21424'), ('rel', 'http://www.wikidata.org/prop/direct/P3107'), ('name', 'LdiF ID')]
# [('p', '712280'), ('rel', 'http://www.wikidata.org/prop/direct/P3129'), ('name', 'cine.gr film ID')]
# [('p', '65'), ('rel', 'http://www.wikidata.org/prop/direct/P3138'), ('name', 'OFDb film ID')]
# [('p', 't0004658'), ('rel', 'http://www.wikidata.org/prop/direct/P3141'), ('name', 'EDb film ID')]
# [('p', '97144'), ('rel', 'http://www.wikidata.org/prop/direct/P3143'), ('name', 'elFilm film ID')]
# [('p', '11361'), ('rel', 'http://www.wikidata.org/prop/direct/P3302'), ('name', 'Open Media Database film ID')]
# [('p', 'http://www.wikidata.org/entity/Q7343629'), ('rel', 'http://www.wikidata.org/prop/direct/P344'), ('name', 'director of photography')]
# [('p', 'tt0097474'), ('rel', 'http://www.wikidata.org/prop/direct/P345'), ('name', 'IMDb ID')]
# [('p', '58103'), ('rel', 'http://www.wikidata.org/prop/direct/P3593'), ('name', 'AFI Catalog of Feature Films ID')]
# [('p', 'http://www.wikidata.org/entity/Q1860'), ('rel', 'http://www.wikidata.org/prop/direct/P364'), ('name', 'original language of film or TV show')]
# [('p', '127561'), ('rel', 'http://www.wikidata.org/prop/direct/P3804'), ('name', 'TV Guide show ID (former scheme)')]
# [('p', '1396'), ('rel', 'http://www.wikidata.org/prop/direct/P3844'), ('name', 'Deutsche Synchronkartei film ID')]
# [('p', '1302032'), ('rel', 'http://www.wikidata.org/prop/direct/P3933'), ('name', 'Cinema.de ID')]
# [('p', 'http://www.wikidata.org/entity/Q723685'), ('rel', 'http://www.wikidata.org/prop/direct/P437'), ('name', 'distribution format')]
# [('p', '1295166'), ('rel', 'http://www.wikidata.org/prop/direct/P4529'), ('name', 'Douban film ID')]
# [('p', 'http://www.wikidata.org/entity/Q22006653'), ('rel', 'http://www.wikidata.org/prop/direct/P462'), ('name', 'color')]
# [('p', '6400'), ('rel', 'http://www.wikidata.org/prop/direct/P4665'), ('name', 'CineMagia title ID')]
# [('p', '70456'), ('rel', 'http://www.wikidata.org/prop/direct/P4780'), ('name', 'MYmovies movie ID')]
# [('p', '456968'), ('rel', 'http://www.wikidata.org/prop/direct/P480'), ('name', 'FilmAffinity ID')]
# [('p', '11361'), ('rel', 'http://www.wikidata.org/prop/direct/P4947'), ('name', 'TMDb movie ID')]
# [('p', 'http://www.wikidata.org/entity/Q30'), ('rel', 'http://www.wikidata.org/prop/direct/P495'), ('name', 'country of origin')]
# [('p', '34736'), ('rel', 'http://www.wikidata.org/prop/direct/P5032'), ('name', 'Filmweb.pl film ID')]
# [('p', 'http://www.wikidata.org/entity/Q117234'), ('rel', 'http://www.wikidata.org/prop/direct/P57'), ('name', 'director')]
# [('p', '1989-01-01T00:00:00Z'), ('rel', 'http://www.wikidata.org/prop/direct/P577'), ('name', 'publication date')]
# [('p', '1991-07-11T00:00:00Z'), ('rel', 'http://www.wikidata.org/prop/direct/P577'), ('name', 'publication date')]
# [('p', 'halloween-v-die-rache-des-michael-myers'), ('rel', 'http://www.wikidata.org/prop/direct/P5786'), ('name', 'Moviepilot.de film ID')]
# [('p', 'http://www.wikidata.org/entity/Q95008'), ('rel', 'http://www.wikidata.org/prop/direct/P58'), ('name', 'screenwriter')]
# [('p', 'http://www.wikidata.org/entity/Q117234'), ('rel', 'http://www.wikidata.org/prop/direct/P58'), ('name', 'screenwriter')]
# [('p', '4025-722'), ('rel', 'http://www.wikidata.org/prop/direct/P5905'), ('name', 'Comic Vine ID')]
# [('p', 'halloween-5-the-revenge-of-michael-myers'), ('rel', 'http://www.wikidata.org/prop/direct/P6127'), ('name', 'Letterboxd film ID')]
# [('p', 'movies:Halloween_5:_The_Revenge_of_Michael_Myers'), ('rel', 'http://www.wikidata.org/prop/direct/P6262'), ('name', 'Fandom article ID')]
# [('p', 'the80smovies:Halloween_5:_The_Revenge_of_Michael_Myers'), ('rel', 'http://www.wikidata.org/prop/direct/P6262'), ('name', 'Fandom article ID')]
# [('p', '927752262'), ('rel', 'http://www.wikidata.org/prop/direct/P6398'), ('name', 'iTunes movie ID')]
# [('p', '/m/06d6nx'), ('rel', 'http://www.wikidata.org/prop/direct/P646'), ('name', 'Freebase ID')]
# [('p', 'http://www.wikidata.org/entity/Q907311'), ('rel', 'http://www.wikidata.org/prop/direct/P750'), ('name', 'distributed by')]
# [('p', 'http://www.wikidata.org/entity/Q1204'), ('rel', 'http://www.wikidata.org/prop/direct/P840'), ('name', 'narrative location')]
# [('p', 'http://www.halloweenmovies.com'), ('rel', 'http://www.wikidata.org/prop/direct/P856'), ('name', 'official website')]
# [('p', 'http://www.wikidata.org/entity/Q730362'), ('rel', 'http://www.wikidata.org/prop/direct/P86'), ('name', 'composer')]
# [('p', '113532'), ('rel', 'http://www.wikidata.org/prop/direct/P905'), ('name', 'PORT film ID')]
# [('p', 'http://www.wikidata.org/entity/Q829'), ('rel', 'http://www.wikidata.org/prop/direct/P915'), ('name', 'filming location')]
# [('p', 'umc.cmc.4igzhykb2olsno5m2wrdulw6m'), ('rel', 'http://www.wikidata.org/prop/direct/P9586'), ('name', 'Apple TV movie ID')]
# [('p', '17637'), ('rel', 'http://www.wikidata.org/prop/direct/P4277'), ('name', 'Daum movie ID')]
# [('p', '1264'), ('rel', 'http://www.wikidata.org/prop/direct/P7975'), ('name', 'Filmfront film ID')]
# [('p', 'http://www.wikidata.org/entity/Q251868'), ('rel', 'http://www.wikidata.org/prop/direct/P9215'), ('name', 'set during recurring event')]
# 87

# %%
 #i found cost:P2130 for each film and in the query before i found buget P2769 for each film

# %%
#here i get all the relationship with the  halloween serie Q1364022 found before

queryString = """
SELECT ?p ?rel ?name
WHERE { 

wd:Q1364022 ?rel ?p.
# ?rel <http://schema.org/name> ?name .
} LIMIT 200
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('p', 'halloween'), ('rel', 'http://www.wikidata.org/prop/direct/P2530'), ('name', 'Box Office Mojo franchise ID (former scheme)')]
# [('p', 'franchise/halloween'), ('rel', 'http://www.wikidata.org/prop/direct/P1258'), ('name', 'Rotten Tomatoes ID')]
# [('p', 'http://www.wikidata.org/entity/Q853630'), ('rel', 'http://www.wikidata.org/prop/direct/P136'), ('name', 'genre')]
# [('p', 'http://www.wikidata.org/entity/Q10547782'), ('rel', 'http://www.wikidata.org/prop/direct/P1424'), ('name', "topic's main template")]
# [('p', 'Halloween'), ('rel', 'http://www.wikidata.org/prop/direct/P1476'), ('name', 'title')]
# [('p', 'http://www.wikidata.org/entity/Q229620'), ('rel', 'http://www.wikidata.org/prop/direct/P1889'), ('name', 'different from')]
# [('p', 'http://www.wikidata.org/entity/Q24856'), ('rel', 'http://www.wikidata.org/prop/direct/P31'), ('name', 'instance of')]
# [('p', 'http://www.wikidata.org/entity/Q196600'), ('rel', 'http://www.wikidata.org/prop/direct/P31'), ('name', 'instance of')]
# [('p', 'http://www.wikidata.org/entity/Q1860'), ('rel', 'http://www.wikidata.org/prop/direct/P364'), ('name', 'original language of film or TV show')]
# [('p', 'Halloween (franchise)'), ('rel', 'http://www.wikidata.org/prop/direct/P373'), ('name', 'Commons category')]
# [('p', 'http://www.wikidata.org/entity/Q30'), ('rel', 'http://www.wikidata.org/prop/direct/P495'), ('name', 'country of origin')]
# [('p', 'http://www.wikidata.org/entity/Q85997053'), ('rel', 'http://www.wikidata.org/prop/direct/P527'), ('name', 'has part')]
# [('p', 'http://www.wikidata.org/entity/Q1050815'), ('rel', 'http://www.wikidata.org/prop/direct/P527'), ('name', 'has part')]
# [('p', 'http://www.wikidata.org/entity/Q976728'), ('rel', 'http://www.wikidata.org/prop/direct/P527'), ('name', 'has part')]
# [('p', 'http://www.wikidata.org/entity/Q20666646'), ('rel', 'http://www.wikidata.org/prop/direct/P527'), ('name', 'has part')]
# [('p', 'http://www.wikidata.org/entity/Q909063'), ('rel', 'http://www.wikidata.org/prop/direct/P527'), ('name', 'has part')]
# [('p', 'http://www.wikidata.org/entity/Q203705'), ('rel', 'http://www.wikidata.org/prop/direct/P527'), ('name', 'has part')]
# [('p', 'http://www.wikidata.org/entity/Q221103'), ('rel', 'http://www.wikidata.org/prop/direct/P527'), ('name', 'has part')]
# [('p', 'http://www.wikidata.org/entity/Q959853'), ('rel', 'http://www.wikidata.org/prop/direct/P527'), ('name', 'has part')]
# [('p', 'http://www.wikidata.org/entity/Q850312'), ('rel', 'http://www.wikidata.org/prop/direct/P527'), ('name', 'has part')]
# [('p', 'http://www.wikidata.org/entity/Q1138055'), ('rel', 'http://www.wikidata.org/prop/direct/P527'), ('name', 'has part')]
# [('p', 'http://www.wikidata.org/entity/Q67279679'), ('rel', 'http://www.wikidata.org/prop/direct/P527'), ('name', 'has part')]
# [('p', 'http://www.wikidata.org/entity/Q176488'), ('rel', 'http://www.wikidata.org/prop/direct/P527'), ('name', 'has part')]
# [('p', 'http://www.wikidata.org/entity/Q908690'), ('rel', 'http://www.wikidata.org/prop/direct/P527'), ('name', 'has part')]
# [('p', '/m/09twsw'), ('rel', 'http://www.wikidata.org/prop/direct/P646'), ('name', 'Freebase ID')]
# [('p', 'Halloween_(série_de_films)'), ('rel', 'http://www.wikidata.org/prop/direct/P7818'), ('name', 'French Vikidia ID')]
# [('p', 'http://www.wikidata.org/entity/Q6456912'), ('rel', 'http://www.wikidata.org/prop/direct/P910'), ('name', "topic's main category")]
# [('p', 'http://www.wikidata.org/entity/Q251868'), ('rel', 'http://www.wikidata.org/prop/direct/P9215'), ('name', 'set during recurring event')]
# 28

# %%
#I found no relationship which indicates rating (apart for age ratings ex 18+) whith the Hallowing serie and 2 Halloween films 
#so a possible comparrison with the current information is impossible
#the only idea i have is to look through the links of other sites such as metacritics or wrotten tomatoes wich i have found

# %%
#Investigate which franchise costed more
#in the previous queries i found cost:P2130 for each film and in the query before i found buget P2769 for each film
#in this query i return the cost for each film
queryString = """
SELECT DISTINCT  ?film ?cost
WHERE { 
{
#this are the films part of the Halloween franciase
# ?film wdt:P179 wd:Q1364022.
# ?film wdt:P2130 ?cost.
}
UNION
{
# ?film wdt:P179 wd:Q1138878.
# ?film wdt:P2130 ?cost.

}
UNION
{
# ?film wdt:P179 wd:Q1138878.
# ?film wdt:P2769 ?cost.

}
UNION
{
# ?film wdt:P179 wd:Q1364022.
# ?film wdt:P2769 ?cost.

}
}
LIMIT 50
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('film', 'http://www.wikidata.org/entity/Q221103'), ('cost', '325000')]
# [('film', 'http://www.wikidata.org/entity/Q1243009'), ('cost', '1250000')]
# [('film', 'http://www.wikidata.org/entity/Q1243013'), ('cost', '2250000')]
# [('film', 'http://www.wikidata.org/entity/Q1454798'), ('cost', '2800000')]
# [('film', 'http://www.wikidata.org/entity/Q1454799'), ('cost', '3000000')]
# [('film', 'http://www.wikidata.org/entity/Q1243019'), ('cost', '2600000')]
# [('film', 'http://www.wikidata.org/entity/Q176488'), ('cost', '15000000')]
# [('film', 'http://www.wikidata.org/entity/Q909063'), ('cost', '15000000')]
# [('film', 'http://www.wikidata.org/entity/Q203705'), ('cost', '2500000')]
# [('film', 'http://www.wikidata.org/entity/Q976728'), ('cost', '3000000')]
# [('film', 'http://www.wikidata.org/entity/Q1138055'), ('cost', '5000000')]
# 11

# %%
#in this query i return the total cost for each franchise
queryString = """



SELECT DISTINCT  ?serie SUM(?cost) AS ?cost
WHERE { 
{
#this are the films part of the Halloween franciase
# ?film wdt:P179 wd:Q1364022.
# ?film wdt:P2130 ?cost.
# ?film wdt:P179 ?serie.
}
UNION
{
# ?film wdt:P179 wd:Q1138878.
# ?film wdt:P2130 ?cost.
# ?film wdt:P179 ?serie.

}
UNION
{
# ?film wdt:P179 wd:Q1138878.
# ?film wdt:P2769 ?cost.
# ?film wdt:P179 ?serie.

}
UNION
{
# ?film wdt:P179 wd:Q1364022.
# ?film wdt:P2769 ?cost.
# ?film wdt:P179 ?serie.

}
}GROUP BY(?serie)
LIMIT 50
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('serie', 'http://www.wikidata.org/entity/Q1364022'), ('cost', '40825000')]
# [('serie', 'http://www.wikidata.org/entity/Q1138878'), ('cost', '11900000')]
# 2

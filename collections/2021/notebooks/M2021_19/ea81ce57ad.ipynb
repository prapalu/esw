# %% [markdown]
# # General instructions
#
# The goal of the project is to materialize a set of **exploratory workloads** over a real-world, large-scale,  open-domain KG: [WikiData](https://www.wikidata.org/wiki/Wikidata:Main_Page)
#
# An exploratory workload  is composed by a set of queries, where each query is related to the information obtained previously.
#
# An exploratory workload starts with a usually vague, open ended question, and does not assume the person issuing the workload has a clear understanding of the data contained in the target database or its structure.
#
# Remeber that:
#
# 1. All the queries must run in the python notebook
# 2. You can use classes and properties only if you find them via a SPARQL query that must be present in the notebook
# 3. You do not delete useless queries. Keep everything that is synthatically valid
#
# ```
# ?p <http://schema.org/name> ?name .
# ```
#
# is the BGP returning a human-readable name of a property or a class in Wikidata.

# %%
## SETUP used later

from SPARQLWrapper import SPARQLWrapper, JSON


prefixString = """
##-ea81ce57ad-##
PREFIX wd: <http://www.wikidata.org/entity/> 
PREFIX wdt: <http://www.wikidata.org/prop/direct/> 
PREFIX sc: <http://schema.org/>
"""

# select and construct queries
def run_query(queryString):
    to_run = prefixString + "\n" + queryString

    sparql = SPARQLWrapper("http://a256-gc1-02.srv.aau.dk:5820/sparql")
    sparql.setTimeout(300)
    sparql.setReturnFormat(JSON)
    sparql.setQuery(to_run)

    try :
       results = sparql.query()
       json_results = results.convert()
       if len(json_results['results']['bindings'])==0:
          print("Empty")
          return 0
    
       for bindings in json_results['results']['bindings']:
          print( [ (var, value['value'])  for var, value in bindings.items() ] )

       return len(json_results['results']['bindings'])

    except Exception as e :
        print("The operation failed", e)
    
# ASk queries
def run_ask_query(queryString):
    to_run = prefixString + "\n" + queryString

    sparql = SPARQLWrapper("http://a256-gc1-02.srv.aau.dk:5820/sparql")
    sparql.setTimeout(300)
    sparql.setReturnFormat(JSON)
    sparql.setQuery(to_run)

    try :
        return sparql.query().convert()

    except Exception as e :
        print("The operation failed", e)

# %% [markdown]
# # Companies Workflow Series ("IT Companies explorative search")
#
# Consider the following exploratory information need:
#
# > Compare companies across different sectors in U.K., U.S., and Canada, consider number of employees, companies owned or acquired, and revenue or assets

# %% [markdown]
# ## Useful URIs for the current workflow
#
#
# The following are given:
#
# | IRI           | Description   | Role      |
# | -----------   | -----------   |-----------|
# | `wdt:P1647`   | subproperty   | predicate |
# | `wdt:P31`     | instance of   | predicate |
# | `wdt:P279`    | subclass      | predicate |
# | `wdt:P17`      | country       | predicate |
# | `wd:Q4830453`  | Business      | node      |
# | `wd:Q13977`    | Bloomberg L.P.| node |
# | `wd:Q502121`   | BlackBerry    | node |
# | `wd:Q16`        | Canada        | node |
# | `wd:Q145`      | U.K.          | node |
# | `wd:Q30`       | U.S.A.        | node |
#
#
# Also consider
#
# ```
# ?p wdt:P17 wd:Q16  .
# ?p wdt:P31 wd:Q4830453  .
# ```
#
# is the BGP to retrieve all **canadian businesses**

# %% [markdown]
# ## Workload Goals
#
# 1. Identify the BGP for obtaining number of employees of a company and other relevant numerical attributes
#
# 2. Identify the BGP to retrieve all companies owned by a company
#
# 3. Is there some company that owns companies in other countries?
#
# 4. Companies have different 'legal forms', compare the number of companies divided in different legal forms
#
# 5. Analyze the number of employees  and other relevant numeric attributes
#
#    5.1 What are the top-10 companies for a given attribute?
#
#    5.2 For which companies is defined some form of income or market capitalization or total assets? What is the min, max, and average in each category and country?
#
#    5.3 Which business in each country owns more businesses in other countries?

# %%
# start your workflow here

# %%
queryString = """
SELECT COUNT(*)
WHERE { 

# ?p wdt:P17 wd:Q16  . 
# ?p wdt:P31 wd:Q4830453  . 
} 
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('callret-0', '2482')]
# 1

# %% [markdown]
# **1 - Identify the BGP for obtaining number of employees of a company and other relevant numerical attributes**

# %%
queryString = """
SELECT DISTINCT ?p ?pName
WHERE { 

# ?company wdt:P17 wd:Q16  . 
# ?company wdt:P31 wd:Q4830453  . 
# ?company ?p ?obj .

# ?company <http://schema.org/name> ?cName .
# ?p <http://schema.org/name> ?pName .
} 
ORDER BY ASC(?pName)

"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P6269'), ('pName', 'API endpoint')]
# [('p', 'http://www.wikidata.org/prop/direct/P6150'), ('pName', 'Academy Awards Database nominee ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1661'), ('pName', 'Alexa rank')]
# [('p', 'http://www.wikidata.org/prop/direct/P6683'), ('pName', 'Alexander Turnbull Library ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1728'), ('pName', 'AllMusic artist ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P9618'), ('pName', 'AlternativeTo software ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6276'), ('pName', 'Amazon Music artist ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3276'), ('pName', 'Angel List ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3861'), ('pName', 'App Store app ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5260'), ('pName', 'App Store developer ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2850'), ('pName', 'Apple Music artist ID (American version)')]
# [('p', 'http://www.wikidata.org/prop/direct/P3548'), ('pName', 'Australian Business Number')]
# [('p', 'http://www.wikidata.org/prop/direct/P3551'), ('pName', 'Australian Registered Body Number')]
# [('p', 'http://www.wikidata.org/prop/direct/P3280'), ('pName', 'BAnQ author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5491'), ('pName', "BD Gest' author ID")]
# [('p', 'http://www.wikidata.org/prop/direct/P4081'), ('pName', 'BHL creator ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5361'), ('pName', 'BNB person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2581'), ('pName', 'BabelNet ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3283'), ('pName', 'Bandcamp ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7195'), ('pName', 'Bandsintown artist ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P268'), ('pName', 'Bibliothèque nationale de France ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3377'), ('pName', 'Bloomberg company ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6160'), ('pName', 'BoardGameGeek game publisher ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2531'), ('pName', 'Box Office Mojo studio ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1711'), ('pName', 'British Museum person or institution ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P4725'), ('pName', 'C-SPAN organization ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1273'), ('pName', 'CANTIC ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8860'), ('pName', 'Canada Business Number')]
# [('p', 'http://www.wikidata.org/prop/direct/P5395'), ('pName', 'Canadian Encyclopedia article ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1670'), ('pName', 'Canadiana Authorities ID (former scheme)')]
# [('p', 'http://www.wikidata.org/prop/direct/P8179'), ('pName', 'Canadiana NCF ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5531'), ('pName', 'Central Index Key')]
# [('p', 'http://www.wikidata.org/prop/direct/P5951'), ('pName', 'ComiXology creator ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P9320'), ('pName', 'ComiXology publisher ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5905'), ('pName', 'Comic Vine ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1472'), ('pName', 'Commons Creator page')]
# [('p', 'http://www.wikidata.org/prop/direct/P373'), ('pName', 'Commons category')]
# [('p', 'http://www.wikidata.org/prop/direct/P935'), ('pName', 'Commons gallery')]
# [('p', 'http://www.wikidata.org/prop/direct/P3225'), ('pName', 'Corporate Number (Japan)')]
# [('p', 'http://www.wikidata.org/prop/direct/P3153'), ('pName', 'Crossref funder ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8375'), ('pName', 'Crossref journal ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2088'), ('pName', 'Crunchbase organization ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2771'), ('pName', 'D-U-N-S number')]
# [('p', 'http://www.wikidata.org/prop/direct/P7951'), ('pName', 'DC Comics talent ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P9560'), ('pName', 'DCinemaToday company ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P356'), ('pName', 'DOI')]
# [('p', 'http://www.wikidata.org/prop/direct/P1662'), ('pName', 'DOI prefix')]
# [('p', 'http://www.wikidata.org/prop/direct/P2942'), ('pName', 'Dailymotion channel ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P9319'), ('pName', 'Dark Horse creator ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5308'), ('pName', 'Dictionary of Scottish Architects ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1953'), ('pName', 'Discogs artist ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1955'), ('pName', 'Discogs label ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7306'), ('pName', 'Downdetector ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5785'), ('pName', 'EU Research participant ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2657'), ('pName', 'EU Transparency Register ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3608'), ('pName', 'EU VAT number')]
# [('p', 'http://www.wikidata.org/prop/direct/P9279'), ('pName', 'Egapro gender equality index')]
# [('p', 'http://www.wikidata.org/prop/direct/P1417'), ('pName', 'Encyclopædia Britannica Online ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3482'), ('pName', 'Europeana Fashion creator ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7704'), ('pName', 'Europeana entity')]
# [('p', 'http://www.wikidata.org/prop/direct/P2163'), ('pName', 'FAST ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2013'), ('pName', 'Facebook ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P4003'), ('pName', 'Facebook page ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6262'), ('pName', 'Fandom article ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7438'), ('pName', 'FantLab publisher ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3267'), ('pName', 'Flickr user ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P4107'), ('pName', 'Framalibre ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P646'), ('pName', 'Freebase ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7818'), ('pName', 'French Vikidia ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P9432'), ('pName', 'GCD publisher ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P227'), ('pName', 'GND ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2427'), ('pName', 'GRID ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7997'), ('pName', 'GRY-Online company ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6182'), ('pName', 'GameFAQs company ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7521'), ('pName', 'Gaming-History company ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1566'), ('pName', 'GeoNames ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5247'), ('pName', 'Giant Bomb ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P4013'), ('pName', 'Giphy username')]
# [('p', 'http://www.wikidata.org/prop/direct/P2037'), ('pName', 'GitHub username')]
# [('p', 'http://www.wikidata.org/prop/direct/P8060'), ('pName', 'Glassdoor company ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7502'), ('pName', 'Golden ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2671'), ('pName', 'Google Knowledge Graph ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3749'), ('pName', 'Google Maps Customer ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5337'), ('pName', 'Google News topics ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3418'), ('pName', 'Google Play Store app ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2847'), ('pName', 'Google+ ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1296'), ('pName', 'Gran Enciclopèdia Catalana ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8406'), ('pName', 'Grove Art Online ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8903'), ('pName', 'HAL journal ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6773'), ('pName', 'HAL structure ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7982'), ('pName', 'Hrvatska enciklopedija ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P229'), ('pName', 'IATA airline designator')]
# [('p', 'http://www.wikidata.org/prop/direct/P230'), ('pName', 'ICAO airline designator')]
# [('p', 'http://www.wikidata.org/prop/direct/P345'), ('pName', 'IMDb ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P458'), ('pName', 'IMO ship number')]
# [('p', 'http://www.wikidata.org/prop/direct/P3761'), ('pName', 'IPv4 routing prefix')]
# [('p', 'http://www.wikidata.org/prop/direct/P3793'), ('pName', 'IPv6 routing prefix')]
# [('p', 'http://www.wikidata.org/prop/direct/P1297'), ('pName', 'IRS Employer Identification Number')]
# [('p', 'http://www.wikidata.org/prop/direct/P3035'), ('pName', 'ISBN publisher prefix')]
# [('p', 'http://www.wikidata.org/prop/direct/P946'), ('pName', 'ISIN')]
# [('p', 'http://www.wikidata.org/prop/direct/P213'), ('pName', 'ISNI')]
# [('p', 'http://www.wikidata.org/prop/direct/P2627'), ('pName', 'ISO 9362 SWIFT/BIC code')]
# [('p', 'http://www.wikidata.org/prop/direct/P236'), ('pName', 'ISSN')]
# [('p', 'http://www.wikidata.org/prop/direct/P7363'), ('pName', 'ISSN-L')]
# [('p', 'http://www.wikidata.org/prop/direct/P3743'), ('pName', 'ITU/ISO/IEC object identifier')]
# [('p', 'http://www.wikidata.org/prop/direct/P269'), ('pName', 'IdRef ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2003'), ('pName', 'Instagram username')]
# [('p', 'http://www.wikidata.org/prop/direct/P9650'), ('pName', 'Internet Game Database company ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8408'), ('pName', 'KBpedia ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3192'), ('pName', 'Last.fm ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7810'), ('pName', 'LaunchBox Games Database publisher ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7784'), ('pName', 'LaunchBox Games Database developer ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1278'), ('pName', 'Legal Entity Identifier')]
# [('p', 'http://www.wikidata.org/prop/direct/P409'), ('pName', 'Libraries Australia ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P244'), ('pName', 'Library of Congress authority ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P4264'), ('pName', 'LinkedIn company ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3393'), ('pName', 'LittleSis organization ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3258'), ('pName', 'LiveJournal ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P4776'), ('pName', 'MAC Address Block Large ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7534'), ('pName', 'MIC market code')]
# [('p', 'http://www.wikidata.org/prop/direct/P6422'), ('pName', 'ManualsLib brand ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7950'), ('pName', 'Marvel Comics creators ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7886'), ('pName', 'Media Arts Database ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P9852'), ('pName', 'Media Bias/Fact Check ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3899'), ('pName', 'Medium username')]
# [('p', 'http://www.wikidata.org/prop/direct/P4573'), ('pName', 'Merchant Category Code')]
# [('p', 'http://www.wikidata.org/prop/direct/P6366'), ('pName', 'Microsoft Academic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P4730'), ('pName', 'Mir@bel journal ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P4773'), ('pName', 'MobyGames company ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P9035'), ('pName', 'Muck Rack media outlet ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2174'), ('pName', 'Museum of Modern Art artist ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P434'), ('pName', 'MusicBrainz artist ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P966'), ('pName', 'MusicBrainz label ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1004'), ('pName', 'MusicBrainz place ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3224'), ('pName', 'NAICS code')]
# [('p', 'http://www.wikidata.org/prop/direct/P691'), ('pName', 'NKCR AUT ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1315'), ('pName', 'NLA Trove ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1695'), ('pName', 'NLP ID (unique)')]
# [('p', 'http://www.wikidata.org/prop/direct/P1015'), ('pName', 'NORAF ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1207'), ('pName', 'NUKAT ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8885'), ('pName', 'Namuwiki ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P349'), ('pName', 'National Diet Library ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P9495'), ('pName', 'National Historical Museums of Sweden agent ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P949'), ('pName', 'National Library of Israel ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3348'), ('pName', 'National Library of Greece ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3221'), ('pName', 'New York Times topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7570'), ('pName', 'OGDB company ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8253'), ('pName', 'OSM Name Suggestion Index identifier')]
# [('p', 'http://www.wikidata.org/prop/direct/P648'), ('pName', 'Open Library ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1320'), ('pName', 'OpenCorporates ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5256'), ('pName', 'OpenCorporates corporate grouping')]
# [('p', 'http://www.wikidata.org/prop/direct/P8735'), ('pName', 'Opta football competition ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7293'), ('pName', 'PLWABN ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P4293'), ('pName', 'PM20 folder ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3347'), ('pName', 'PermID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3836'), ('pName', 'Pinterest username')]
# [('p', 'http://www.wikidata.org/prop/direct/P1938'), ('pName', 'Project Gutenberg author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7403'), ('pName', 'Publons publisher ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3417'), ('pName', 'Quora topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2592'), ('pName', 'Québec cultural heritage directory people identifier')]
# [('p', 'http://www.wikidata.org/prop/direct/P6782'), ('pName', 'ROR ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3500'), ('pName', 'Ringgold ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6617'), ('pName', 'RoMEO publisher ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2751'), ('pName', 'Roller Coaster Database ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3987'), ('pName', 'SHARE Catalogue author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3242'), ('pName', 'SIC code')]
# [('p', 'http://www.wikidata.org/prop/direct/P1616'), ('pName', 'SIREN number')]
# [('p', 'http://www.wikidata.org/prop/direct/P7708'), ('pName', 'SNESmusic.org company ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1156'), ('pName', 'Scopus source ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2984'), ('pName', 'Snapchat username')]
# [('p', 'http://www.wikidata.org/prop/direct/P3478'), ('pName', 'Songkick artist ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3040'), ('pName', 'SoundCloud ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1902'), ('pName', 'Spotify artist ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1482'), ('pName', 'Stack Exchange tag')]
# [('p', 'http://www.wikidata.org/prop/direct/P6460'), ('pName', 'Swedish Organization Number')]
# [('p', 'http://www.wikidata.org/prop/direct/P6839'), ('pName', 'TV Tropes identifier')]
# [('p', 'http://www.wikidata.org/prop/direct/P5456'), ('pName', 'TasteAtlas ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P4204'), ('pName', 'The Times of India topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7157'), ('pName', 'The Top Tens ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7634'), ('pName', 'TheGamesDB developer ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7642'), ('pName', 'TheGamesDB publisher ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7085'), ('pName', 'TikTok username')]
# [('p', 'http://www.wikidata.org/prop/direct/P5161'), ('pName', 'Trustpilot company ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8672'), ('pName', 'Twitter topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2002'), ('pName', 'Twitter username')]
# [('p', 'http://www.wikidata.org/prop/direct/P4527'), ('pName', 'UK Parliament thesaurus ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1167'), ('pName', 'USB vendor ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7560'), ('pName', 'UVL company ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3979'), ('pName', 'Unifrance company ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P245'), ('pName', 'Union List of Artist Names ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P214'), ('pName', 'VIAF ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3185'), ('pName', 'VK ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1928'), ('pName', 'Vaccine Ontology ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P4015'), ('pName', 'Vimeo identifier')]
# [('p', 'http://www.wikidata.org/prop/direct/P9242'), ('pName', 'Whiskybase distillery ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6766'), ('pName', "Who's on First ID")]
# [('p', 'http://www.wikidata.org/prop/direct/P1687'), ('pName', 'Wikidata property')]
# [('p', 'http://www.wikidata.org/prop/direct/P4839'), ('pName', 'Wolfram Language entity code')]
# [('p', 'http://www.wikidata.org/prop/direct/P7859'), ('pName', 'WorldCat Identities ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2397'), ('pName', 'YouTube channel ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1651'), ('pName', 'YouTube video ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3553'), ('pName', 'Zhihu topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P9239'), ('pName', 'affiliated worker organisation')]
# [('p', 'http://www.wikidata.org/prop/direct/P5703'), ('pName', 'airline accounting code')]
# [('p', 'http://www.wikidata.org/prop/direct/P114'), ('pName', 'airline alliance')]
# [('p', 'http://www.wikidata.org/prop/direct/P113'), ('pName', 'airline hub')]
# [('p', 'http://www.wikidata.org/prop/direct/P6949'), ('pName', 'announcement date')]
# [('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction')]
# [('p', 'http://www.wikidata.org/prop/direct/P5508'), ('pName', 'archINFORM person or group ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P485'), ('pName', 'archives at')]
# [('p', 'http://www.wikidata.org/prop/direct/P2046'), ('pName', 'area')]
# [('p', 'http://www.wikidata.org/prop/direct/P4103'), ('pName', 'assets under management')]
# [('p', 'http://www.wikidata.org/prop/direct/P3797'), ('pName', 'autonomous system number')]
# [('p', 'http://www.wikidata.org/prop/direct/P166'), ('pName', 'award received')]
# [('p', 'http://www.wikidata.org/prop/direct/P3320'), ('pName', 'board member')]
# [('p', 'http://www.wikidata.org/prop/direct/P199'), ('pName', 'business division')]
# [('p', 'http://www.wikidata.org/prop/direct/P2317'), ('pName', 'call sign')]
# [('p', 'http://www.wikidata.org/prop/direct/P432'), ('pName', 'callsign of airline')]
# [('p', 'http://www.wikidata.org/prop/direct/P3876'), ('pName', 'category for alumni of educational institution')]
# [('p', 'http://www.wikidata.org/prop/direct/P770'), ('pName', 'cause of destruction')]
# [('p', 'http://www.wikidata.org/prop/direct/P488'), ('pName', 'chairperson')]
# [('p', 'http://www.wikidata.org/prop/direct/P6378'), ('pName', 'charter URL')]
# [('p', 'http://www.wikidata.org/prop/direct/P169'), ('pName', 'chief executive officer')]
# [('p', 'http://www.wikidata.org/prop/direct/P94'), ('pName', 'coat of arms image')]
# [('p', 'http://www.wikidata.org/prop/direct/P4771'), ('pName', 'compArt institution ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5009'), ('pName', 'complies with')]
# [('p', 'http://www.wikidata.org/prop/direct/P275'), ('pName', 'copyright license')]
# [('p', 'http://www.wikidata.org/prop/direct/P6216'), ('pName', 'copyright status')]
# [('p', 'http://www.wikidata.org/prop/direct/P2828'), ('pName', 'corporate officer')]
# [('p', 'http://www.wikidata.org/prop/direct/P17'), ('pName', 'country')]
# [('p', 'http://www.wikidata.org/prop/direct/P495'), ('pName', 'country of origin')]
# [('p', 'http://www.wikidata.org/prop/direct/P2012'), ('pName', 'cuisine')]
# [('p', 'http://www.wikidata.org/prop/direct/P3999'), ('pName', 'date of official closure')]
# [('p', 'http://www.wikidata.org/prop/direct/P1619'), ('pName', 'date of official opening')]
# [('p', 'http://www.wikidata.org/prop/direct/P1299'), ('pName', 'depicted by')]
# [('p', 'http://www.wikidata.org/prop/direct/P973'), ('pName', 'described at URL')]
# [('p', 'http://www.wikidata.org/prop/direct/P1343'), ('pName', 'described by source')]
# [('p', 'http://www.wikidata.org/prop/direct/P1889'), ('pName', 'different from')]
# [('p', 'http://www.wikidata.org/prop/direct/P1037'), ('pName', 'director / manager')]
# [('p', 'http://www.wikidata.org/prop/direct/P2669'), ('pName', 'discontinued date')]
# [('p', 'http://www.wikidata.org/prop/direct/P576'), ('pName', 'dissolved, abolished or demolished date')]
# [('p', 'http://www.wikidata.org/prop/direct/P750'), ('pName', 'distributed by')]
# [('p', 'http://www.wikidata.org/prop/direct/P2044'), ('pName', 'elevation above sea level')]
# [('p', 'http://www.wikidata.org/prop/direct/P968'), ('pName', 'email address')]
# [('p', 'http://www.wikidata.org/prop/direct/P1128'), ('pName', 'employees')]
# [('p', 'http://www.wikidata.org/prop/direct/P8340'), ('pName', 'estimated value')]
# [('p', 'http://www.wikidata.org/prop/direct/P2257'), ('pName', 'event interval')]
# [('p', 'http://www.wikidata.org/prop/direct/P1269'), ('pName', 'facet of')]
# [('p', 'http://www.wikidata.org/prop/direct/P734'), ('pName', 'family name')]
# [('p', 'http://www.wikidata.org/prop/direct/P2900'), ('pName', 'fax number')]
# [('p', 'http://www.wikidata.org/prop/direct/P101'), ('pName', 'field of work')]
# [('p', 'http://www.wikidata.org/prop/direct/P41'), ('pName', 'flag image')]
# [('p', 'http://www.wikidata.org/prop/direct/P5579'), ('pName', 'flight-report.com Airline identifier')]
# [('p', 'http://www.wikidata.org/prop/direct/P156'), ('pName', 'followed by')]
# [('p', 'http://www.wikidata.org/prop/direct/P155'), ('pName', 'follows')]
# [('p', 'http://www.wikidata.org/prop/direct/P112'), ('pName', 'founded by')]
# [('p', 'http://www.wikidata.org/prop/direct/P953'), ('pName', 'full work available at URL')]
# [('p', 'http://www.wikidata.org/prop/direct/P136'), ('pName', 'genre')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part')]
# [('p', 'http://www.wikidata.org/prop/direct/P2670'), ('pName', 'has parts of the class')]
# [('p', 'http://www.wikidata.org/prop/direct/P6379'), ('pName', 'has works in the collection')]
# [('p', 'http://www.wikidata.org/prop/direct/P2572'), ('pName', 'hashtag')]
# [('p', 'http://www.wikidata.org/prop/direct/P159'), ('pName', 'headquarters location')]
# [('p', 'http://www.wikidata.org/prop/direct/P2813'), ('pName', 'house publication')]
# [('p', 'http://www.wikidata.org/prop/direct/P18'), ('pName', 'image')]
# [('p', 'http://www.wikidata.org/prop/direct/P571'), ('pName', 'inception')]
# [('p', 'http://www.wikidata.org/prop/direct/P8875'), ('pName', 'indexed in bibliographic review')]
# [('p', 'http://www.wikidata.org/prop/direct/P452'), ('pName', 'industry')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('p', 'http://www.wikidata.org/prop/direct/P217'), ('pName', 'inventory number')]
# [('p', 'http://www.wikidata.org/prop/direct/P1951'), ('pName', 'investor')]
# [('p', 'http://www.wikidata.org/prop/direct/P121'), ('pName', 'item operated')]
# [('p', 'http://www.wikidata.org/prop/direct/P407'), ('pName', 'language of work or name')]
# [('p', 'http://www.wikidata.org/prop/direct/P2500'), ('pName', 'league level below')]
# [('p', 'http://www.wikidata.org/prop/direct/P1454'), ('pName', 'legal form')]
# [('p', 'http://www.wikidata.org/prop/direct/P2043'), ('pName', 'length')]
# [('p', 'http://www.wikidata.org/prop/direct/P1408'), ('pName', 'licensed to broadcast to')]
# [('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity')]
# [('p', 'http://www.wikidata.org/prop/direct/P421'), ('pName', 'located in time zone')]
# [('p', 'http://www.wikidata.org/prop/direct/P276'), ('pName', 'location')]
# [('p', 'http://www.wikidata.org/prop/direct/P740'), ('pName', 'location of formation')]
# [('p', 'http://www.wikidata.org/prop/direct/P154'), ('pName', 'logo image')]
# [('p', 'http://www.wikidata.org/prop/direct/P921'), ('pName', 'main subject')]
# [('p', 'http://www.wikidata.org/prop/direct/P2226'), ('pName', 'market capitalization')]
# [('p', 'http://www.wikidata.org/prop/direct/P463'), ('pName', 'member of')]
# [('p', 'http://www.wikidata.org/prop/direct/P7888'), ('pName', 'merged into')]
# [('p', 'http://www.wikidata.org/prop/direct/P2259'), ('pName', 'mobile network code')]
# [('p', 'http://www.wikidata.org/prop/direct/P1451'), ('pName', 'motto text')]
# [('p', 'http://www.wikidata.org/prop/direct/P2561'), ('pName', 'name')]
# [('p', 'http://www.wikidata.org/prop/direct/P138'), ('pName', 'named after')]
# [('p', 'http://www.wikidata.org/prop/direct/P1705'), ('pName', 'native label')]
# [('p', 'http://www.wikidata.org/prop/direct/P2295'), ('pName', 'net profit')]
# [('p', 'http://www.wikidata.org/prop/direct/P1411'), ('pName', 'nominated for')]
# [('p', 'http://www.wikidata.org/prop/direct/P800'), ('pName', 'notable work')]
# [('p', 'http://www.wikidata.org/prop/direct/P8368'), ('pName', 'number of branches')]
# [('p', 'http://www.wikidata.org/prop/direct/P1132'), ('pName', 'number of participants')]
# [('p', 'http://www.wikidata.org/prop/direct/P106'), ('pName', 'occupation')]
# [('p', 'http://www.wikidata.org/prop/direct/P1581'), ('pName', 'official blog')]
# [('p', 'http://www.wikidata.org/prop/direct/P1448'), ('pName', 'official name')]
# [('p', 'http://www.wikidata.org/prop/direct/P9549'), ('pName', 'official podcast')]
# [('p', 'http://www.wikidata.org/prop/direct/P856'), ('pName', 'official website')]
# [('p', 'http://www.wikidata.org/prop/direct/P5008'), ('pName', 'on focus list of Wikimedia project')]
# [('p', 'http://www.wikidata.org/prop/direct/P3762'), ('pName', 'openMLOL author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2541'), ('pName', 'operating area')]
# [('p', 'http://www.wikidata.org/prop/direct/P3362'), ('pName', 'operating income')]
# [('p', 'http://www.wikidata.org/prop/direct/P137'), ('pName', 'operator')]
# [('p', 'http://www.wikidata.org/prop/direct/P127'), ('pName', 'owned by')]
# [('p', 'http://www.wikidata.org/prop/direct/P1830'), ('pName', 'owner of')]
# [('p', 'http://www.wikidata.org/prop/direct/P749'), ('pName', 'parent organization')]
# [('p', 'http://www.wikidata.org/prop/direct/P361'), ('pName', 'part of')]
# [('p', 'http://www.wikidata.org/prop/direct/P710'), ('pName', 'participant')]
# [('p', 'http://www.wikidata.org/prop/direct/P1344'), ('pName', 'participant in')]
# [('p', 'http://www.wikidata.org/prop/direct/P2652'), ('pName', 'partnership with')]
# [('p', 'http://www.wikidata.org/prop/direct/P3872'), ('pName', 'patronage')]
# [('p', 'http://www.wikidata.org/prop/direct/P1329'), ('pName', 'phone number')]
# [('p', 'http://www.wikidata.org/prop/direct/P281'), ('pName', 'postal code')]
# [('p', 'http://www.wikidata.org/prop/direct/P7101'), ('pName', 'privacy policy URL')]
# [('p', 'http://www.wikidata.org/prop/direct/P1056'), ('pName', 'product or material produced')]
# [('p', 'http://www.wikidata.org/prop/direct/P2896'), ('pName', 'publication interval')]
# [('p', 'http://www.wikidata.org/prop/direct/P140'), ('pName', 'religion')]
# [('p', 'http://www.wikidata.org/prop/direct/P1366'), ('pName', 'replaced by')]
# [('p', 'http://www.wikidata.org/prop/direct/P1365'), ('pName', 'replaces')]
# [('p', 'http://www.wikidata.org/prop/direct/P1471'), ('pName', 'reporting mark')]
# [('p', 'http://www.wikidata.org/prop/direct/P1875'), ('pName', 'represented by')]
# [('p', 'http://www.wikidata.org/prop/direct/P1268'), ('pName', 'represents')]
# [('p', 'http://www.wikidata.org/prop/direct/P444'), ('pName', 'review score')]
# [('p', 'http://www.wikidata.org/prop/direct/P4446'), ('pName', 'reward program')]
# [('p', 'http://www.wikidata.org/prop/direct/P460'), ('pName', 'said to be the same as')]
# [('p', 'http://www.wikidata.org/prop/direct/P5555'), ('pName', 'schematic')]
# [('p', 'http://www.wikidata.org/prop/direct/P158'), ('pName', 'seal image')]
# [('p', 'http://www.wikidata.org/prop/direct/P4354'), ('pName', 'search formatter URL')]
# [('p', 'http://www.wikidata.org/prop/direct/P6118'), ('pName', 'season ends')]
# [('p', 'http://www.wikidata.org/prop/direct/P4794'), ('pName', 'season starts')]
# [('p', 'http://www.wikidata.org/prop/direct/P1659'), ('pName', 'see also')]
# [('p', 'http://www.wikidata.org/prop/direct/P9138'), ('pName', 'service status information URL')]
# [('p', 'http://www.wikidata.org/prop/direct/P1813'), ('pName', 'short name')]
# [('p', 'http://www.wikidata.org/prop/direct/P793'), ('pName', 'significant event')]
# [('p', 'http://www.wikidata.org/prop/direct/P3342'), ('pName', 'significant person')]
# [('p', 'http://www.wikidata.org/prop/direct/P8972'), ('pName', 'small logo or icon')]
# [('p', 'http://www.wikidata.org/prop/direct/P8687'), ('pName', 'social media followers')]
# [('p', 'http://www.wikidata.org/prop/direct/P2770'), ('pName', 'source of income')]
# [('p', 'http://www.wikidata.org/prop/direct/P989'), ('pName', 'spoken text audio')]
# [('p', 'http://www.wikidata.org/prop/direct/P641'), ('pName', 'sport')]
# [('p', 'http://www.wikidata.org/prop/direct/P580'), ('pName', 'start time')]
# [('p', 'http://www.wikidata.org/prop/direct/P414'), ('pName', 'stock exchange')]
# [('p', 'http://www.wikidata.org/prop/direct/P6375'), ('pName', 'street address')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of')]
# [('p', 'http://www.wikidata.org/prop/direct/P3984'), ('pName', 'subreddit')]
# [('p', 'http://www.wikidata.org/prop/direct/P355'), ('pName', 'subsidiary')]
# [('p', 'http://www.wikidata.org/prop/direct/P7014'), ('pName', 'terms of service URL')]
# [('p', 'http://www.wikidata.org/prop/direct/P1476'), ('pName', 'title')]
# [('p', 'http://www.wikidata.org/prop/direct/P910'), ('pName', "topic's main category")]
# [('p', 'http://www.wikidata.org/prop/direct/P1424'), ('pName', "topic's main template")]
# [('p', 'http://www.wikidata.org/prop/direct/P2403'), ('pName', 'total assets')]
# [('p', 'http://www.wikidata.org/prop/direct/P2137'), ('pName', 'total equity')]
# [('p', 'http://www.wikidata.org/prop/direct/P2139'), ('pName', 'total revenue')]
# [('p', 'http://www.wikidata.org/prop/direct/P6427'), ('pName', 'trading name')]
# [('p', 'http://www.wikidata.org/prop/direct/P366'), ('pName', 'use')]
# [('p', 'http://www.wikidata.org/prop/direct/P1535'), ('pName', 'used by')]
# [('p', 'http://www.wikidata.org/prop/direct/P2283'), ('pName', 'uses')]
# [('p', 'http://www.wikidata.org/prop/direct/P4238'), ('pName', 'webcam page URL')]
# [('p', 'http://www.wikidata.org/prop/direct/P553'), ('pName', 'website account on')]
# [('p', 'http://www.wikidata.org/prop/direct/P937'), ('pName', 'work location')]
# [('p', 'http://www.wikidata.org/prop/direct/P2032'), ('pName', 'work period (end)')]
# [('p', 'http://www.wikidata.org/prop/direct/P2031'), ('pName', 'work period (start)')]
# 365

# %% [markdown]
# Queste potrebbero essere delle propriètà numeriche e/o utili <br>
# [('p', 'http://www.wikidata.org/prop/direct/P4103'), ('pName', 'assets under management')] <br>
# [('p', 'http://www.wikidata.org/prop/direct/P1128'), ('pName', 'employees')] <br>
# [('p', 'http://www.wikidata.org/prop/direct/P8340'), ('pName', 'estimated value')] <br>
# [('p', 'http://www.wikidata.org/prop/direct/P2295'), ('pName', 'net profit')] <br>
# [('p', 'http://www.wikidata.org/prop/direct/P2403'), ('pName', 'total assets')] <br>
# [('p', 'http://www.wikidata.org/prop/direct/P2137'), ('pName', 'total equity')] <br>
# [('p', 'http://www.wikidata.org/prop/direct/P2139'), ('pName', 'total revenue')] <br>
# [('p', 'http://www.wikidata.org/prop/direct/P127'), ('pName', 'owned by')] <br>
# [('p', 'http://www.wikidata.org/prop/direct/P1830'), ('pName', 'owner of')] <br>
# [('p', 'http://www.wikidata.org/prop/direct/P749'), ('pName', 'parent organization')] <br>
# [('p', 'http://www.wikidata.org/prop/direct/P361'), ('pName', 'part of')] <br>
# [('p', 'http://www.wikidata.org/prop/direct/P710'), ('pName', 'participant')] <br>
# [('p', 'http://www.wikidata.org/prop/direct/P1344'), ('pName', 'participant in')] <br>
# [('p', 'http://www.wikidata.org/prop/direct/P2652'), ('pName', 'partnership with')] <br>
# [('p', 'http://www.wikidata.org/prop/direct/P2226'), ('pName', 'market capitalization')] <br>

# %%
queryString = """
SELECT DISTINCT ?cName ?obj
WHERE { 

# ?company wdt:P17 wd:Q16  . 
# ?company wdt:P31 wd:Q4830453  . 
# ?company wdt:P4103 ?obj . #num Asset ?

# ?company <http://schema.org/name> ?cName .
OPTIONAL{?obj <http://schema.org/name> ?objName .}

} 
ORDER BY ASC(?cName)
LIMIT 10
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('cName', 'Brookfield Asset Management'), ('obj', '239825000000')]
# [('cName', 'Caisse de dépôt et placement du Québec'), ('obj', '298500000000')]
# [('cName', 'Great-West Lifeco'), ('obj', '565700000000')]
# [('cName', 'Manulife Financial'), ('obj', '795100000000')]
# [('cName', 'Royal Bank of Canada'), ('obj', '577200000000')]
# [('cName', 'Sun Life Financial'), ('obj', '820800000000')]
# 6

# %%
Esploro le altre proprietà

# %%
queryString = """
SELECT DISTINCT (?cName AS ?companyName) (?obj1 AS ?Asset) (?obj2 AS ?numEm) (?ownby AS ?OwnedBy ) ?obj3 (?parentO AS ?Parent)
WHERE { 

# ?company wdt:P31 wd:Q4830453  . 
OPTIONAL {?company wdt:P4103 ?obj1 .} #num Asset
OPTIONAL {?company wdt:P1128 ?obj2 .} #num employees
OPTIONAL {?company wdt:P127 ?obj3 . #owned by
            # ?obj3 <http://schema.org/name> ?ownby .}
OPTIONAL {?company wdt:P749 ?obj4 . #parent organization
            # ?obj4 <http://schema.org/name> ?parentO .}

# ?company <http://schema.org/name> ?cName .

} 
ORDER BY ASC(?companyName)
LIMIT 500
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('companyName', '"APR"')]
# [('companyName', '"ATOEX"')]
# [('companyName', '"Agentura REPRE" společnost s ručením omezeným')]
# [('companyName', '"BETTINI S.R.L."')]
# [('companyName', '"CZ TOP TRADE s.r.o."')]
# [('companyName', '"ELVE svěřenský fond"')]
# [('companyName', '"Hlásek, spol. s.r.o."')]
# [('companyName', '"K" Line RoRo Bulk Ship Management')]
# [('companyName', '"KF DOMENA" SPÓŁKA Z OGRANICZONA ODPOWIEDZIALNOSCIA')]
# [('companyName', '"Kosmos" Tabak- & Cigarettenfabrik H. F. Wolf')]
# [('companyName', '"Lékárna U nemocnice"')]
# [('companyName', '"Nadace 700 let města Plzně"')]
# [('companyName', '"Nadace Rudolfa Löwyho a plzeňských židů na záchranu plzeňských synagog"')]
# [('companyName', '"R + R"')]
# [('companyName', '"South Bohemia Star" společnost s ručením omezeným')]
# [('companyName', '"Tabak Polska"')]
# [('companyName', '"Yansour" Türkische Zigarettenfabrik H. Kemaleddin & Co. GmbH')]
# [('companyName', '%Arabica')]
# [('companyName', "''CableTV Co,Ltd")]
# [('companyName', "''PDC")]
# [('companyName', "''Pacific Sowa")]
# [('companyName', "'Praha' Wechselseitige Versicherungsanstalt")]
# [('companyName', "'s-Hertogenbosche Stempelfabriek")]
# [('companyName', '(ELEVEN), LLC')]
# [('companyName', '(Shenyang) Northern Heavy Industry Group Co., Ltd')]
# [('companyName', '+H2O (Poland)')]
# [('companyName', '...instore')]
# [('companyName', '01 Communique')]
# [('companyName', '01 Pliroforiki (Greece)')]
# [('companyName', '013 Netvision'), ('Parent', 'Cellcom')]
# [('companyName', '0verflow'), ('numEm', '12')]
# [('companyName', '1 - Cube (Czechia)')]
# [('companyName', '1 Energy')]
# [('companyName', '1 Hacker Way Siopat Suhu')]
# [('companyName', '1 Malaysia Housing Programme')]
# [('companyName', '1 Shevchenka Street, Vynnyky')]
# [('companyName', '1 st plugins')]
# [('companyName', '1%')]
# [('companyName', '1&1 Drillisch'), ('OwnedBy', 'United Internet'), ('obj3', 'http://www.wikidata.org/entity/Q322579'), ('Parent', 'United Internet')]
# [('companyName', '1&1 Telecommunication SE')]
# [('companyName', '1+1 media')]
# [('companyName', '1-2-3 Production'), ('OwnedBy', 'Gazprom-Media'), ('obj3', 'http://www.wikidata.org/entity/Q260542')]
# [('companyName', '1-800 Contacts'), ('OwnedBy', 'AEA Investors'), ('obj3', 'http://www.wikidata.org/entity/Q4651259')]
# [('companyName', '1-800-FREE-411'), ('Parent', 'Liberty Media')]
# [('companyName', '1-800-GET-THIN')]
# [('companyName', '1-800-GOT-JUNK?'), ('OwnedBy', 'Brian Scudamore'), ('obj3', 'http://www.wikidata.org/entity/Q16213063')]
# [('companyName', '1-Page')]
# [('companyName', '1. CORY CZ spol.')]
# [('companyName', '1. Deliace centrum')]
# [('companyName', '1. Distribuční společnost')]
# [('companyName', '1. FK Příbram'), ('numEm', '7'), ('OwnedBy', 'Jan Starka'), ('obj3', 'http://www.wikidata.org/entity/Q95071421')]
# [('companyName', '1. FPX Real')]
# [('companyName', '1. FVE HUMENNÉ')]
# [('companyName', '1. Fond kvalifikovaných investorů Generali PPF Holding B.V. otevřený podílový fond ČP INVEST investiční společnost')]
# [('companyName', '1. Judo club Baník Ostrava, z.s.')]
# [('companyName', '1. Kaspo - Orcar')]
# [('companyName', '1. Kroměřížská investiční')]
# [('companyName', '1. LESNÍ REALITNÍ')]
# [('companyName', '1. PF Slnko, o.p.f., IAD Investments, správ. spol.')]
# [('companyName', '1. Regionální investiční fond SICAV')]
# [('companyName', '1. SK Prostějov, fotbalový klub')]
# [('companyName', '1. SčV, a.s.')]
# [('companyName', '1. VOX')]
# [('companyName', '1. ZO OS KOVO Mohelnice')]
# [('companyName', '1. Zajištěný fond kvalifikovaných investorů otevřený podílový fond ČP INVEST investiční společnost')]
# [('companyName', '1. day')]
# [('companyName', '1. elektrárenská')]
# [('companyName', '1. fond reverzních hypoték SICAV')]
# [('companyName', '1. písecká lesní a dřevařská')]
# [('companyName', '1. správní majetková společnost s. r. o.')]
# [('companyName', '1.Cukerní společnost Praha')]
# [('companyName', '1.Tatranská, akciová spoločnosť'), ('numEm', '40'), ('OwnedBy', 'Airvata Holding'), ('obj3', 'http://www.wikidata.org/entity/Q59754524')]
# [('companyName', '1.účtovníčka')]
# [('companyName', '10 & 10 Danza')]
# [('companyName', '10 Chambers')]
# [('companyName', '10 feet')]
# [('companyName', '10-Gruppen')]
# [('companyName', '100 Bares')]
# [('companyName', '100 Women in Hedge Funds')]
# [('companyName', '100 Worries, LLC')]
# [('companyName', '100% Banco')]
# [('companyName', '100% Capri')]
# [('companyName', '100% REWORK')]
# [('companyName', '1000Memories')]
# [('companyName', '1000Minds')]
# [('companyName', '100MEGA Distribution')]
# [('companyName', '100PROmotion')]
# [('companyName', '100klíčů')]
# [('companyName', '101 Drogerie')]
# [('companyName', '108 Shop')]
# [('companyName', '109CINEMAS')]
# [('companyName', '10Q Reports')]
# [('companyName', '10X Genomics (Sweden)')]
# [('companyName', '10X Genomics (United States)')]
# [('companyName', '10base-t Interactive')]
# [('companyName', '10bet.com')]
# [('companyName', '10th Legion Championship Fighting')]
# [('companyName', '10x')]
# [('companyName', '11. Zajištěný fond kvalifikovaných investorů České pojišťovny')]
# [('companyName', '1111 Job Bank')]
# [('companyName', '112dB')]
# [('companyName', '118000 AG')]
# [('companyName', '11er Nahrungsmittel GmbH')]
# [('companyName', '12 Yard'), ('OwnedBy', 'ITV plc'), ('obj3', 'http://www.wikidata.org/entity/Q3140604'), ('Parent', 'ITV Studios')]
# [('companyName', '12. Zajištěný fond kvalifikovaných investorů')]
# [('companyName', '123 Certification (Canada)')]
# [('companyName', '123 CopyDVD')]
# [('companyName', '123 Money'), ('Parent', 'RSA Insurance Group')]
# [('companyName', '123-reg')]
# [('companyName', '123Net')]
# [('companyName', '123RF.com')]
# [('companyName', '12Auto')]
# [('companyName', '13 Flames Empire')]
# [('companyName', '1366 Technologies')]
# [('companyName', '13CABS')]
# [('companyName', '13Mann')]
# [('companyName', '13Therapeutics (United States)')]
# [('companyName', '13cm')]
# [('companyName', '14 Reels Plus')]
# [('companyName', '14. Zajištěný fond kvalifikovaných investorů otevřený podílový fond ČP INVEST investiční společnost')]
# [('companyName', '140 Proof')]
# [('companyName', '15. Zajištěný fond kvalifikovaných investorů, otevřený podílový fond Generali Investments CEE, investiční společnost')]
# [('companyName', '15Five')]
# [('companyName', '16 Handles')]
# [('companyName', '16. Zajištěný fond kvalifikovaných investorů otevřený podílový fond ČP INVEST investiční společnost')]
# [('companyName', '17 Juin média')]
# [('companyName', '1776')]
# [('companyName', '180 Degree Capital')]
# [('companyName', '1800 Tequila')]
# [('companyName', '1800Mattress.com')]
# [('companyName', '1822direkt'), ('Parent', 'Frankfurter Sparkasse')]
# [('companyName', '1893 from the makers of Pepsi-Cola')]
# [('companyName', '19 Entertainment'), ('Parent', 'CORE Media Group')]
# [('companyName', '1928 Diagnostics (Sweden)')]
# [('companyName', '1988 CSN strike')]
# [('companyName', '19kala'), ('numEm', '70')]
# [('companyName', '1A.lv')]
# [('companyName', '1AVista-Reisen')]
# [('companyName', '1C Company'), ('numEm', '1100')]
# [('companyName', '1C-Rarus')]
# [('companyName', '1CSC')]
# [('companyName', '1Cellbio (United States)')]
# [('companyName', '1Malaysia Development Berhad')]
# [('companyName', '1Spatial (United States)')]
# [('companyName', '1pm')]
# [('companyName', '1pondo')]
# [('companyName', '1seg')]
# [('companyName', '1st Central')]
# [('companyName', '1st Choice Liquor Superstore'), ('Parent', 'Wesfarmers')]
# [('companyName', '1st Constitution Bancorp')]
# [('companyName', '1st Edge (United States)')]
# [('companyName', '1st Round Enterprises')]
# [('companyName', '1st Source')]
# [('companyName', '1st Valley Bank')]
# [('companyName', '1stdibs')]
# [('companyName', '1worldspace')]
# [('companyName', '2 Cheap Cars')]
# [('companyName', '2 Dés Sans Faces')]
# [('companyName', '2 Entertain'), ('OwnedBy', 'Vivendi'), ('obj3', 'http://www.wikidata.org/entity/Q1127887'), ('Parent', 'Vivendi')]
# [('companyName', '2 Entertain'), ('OwnedBy', 'Vivendi'), ('obj3', 'http://www.wikidata.org/entity/Q1127887'), ('Parent', 'Bertelsmann')]
# [('companyName', '2 Entertain'), ('OwnedBy', 'Vivendi'), ('obj3', 'http://www.wikidata.org/entity/Q1127887'), ('Parent', 'BBC')]
# [('companyName', '2 Entertain'), ('OwnedBy', 'Bertelsmann'), ('obj3', 'http://www.wikidata.org/entity/Q156913'), ('Parent', 'Vivendi')]
# [('companyName', '2 Entertain'), ('OwnedBy', 'Bertelsmann'), ('obj3', 'http://www.wikidata.org/entity/Q156913'), ('Parent', 'Bertelsmann')]
# [('companyName', '2 Entertain'), ('OwnedBy', 'Bertelsmann'), ('obj3', 'http://www.wikidata.org/entity/Q156913'), ('Parent', 'BBC')]
# [('companyName', '2 Entertain'), ('OwnedBy', 'BBC'), ('obj3', 'http://www.wikidata.org/entity/Q9531'), ('Parent', 'Vivendi')]
# [('companyName', '2 Entertain'), ('OwnedBy', 'BBC'), ('obj3', 'http://www.wikidata.org/entity/Q9531'), ('Parent', 'Bertelsmann')]
# [('companyName', '2 Entertain'), ('OwnedBy', 'BBC'), ('obj3', 'http://www.wikidata.org/entity/Q9531'), ('Parent', 'BBC')]
# [('companyName', "2 Hrs d'Electricité Du Liban")]
# [('companyName', '2 JCP a.s.')]
# [('companyName', '2 JCP holding')]
# [('companyName', '2 MAX')]
# [('companyName', '2 Player Productions')]
# [('companyName', '2 Ring')]
# [('companyName', '2 Sisters Food Group')]
# [('companyName', '2(x)ist'), ('numEm', '143')]
# [('companyName', '2-DTech (United Kingdom)')]
# [('companyName', '2. Dluhopisový zajištěný otevřený podílový fond Generali Investments CEE, investiční společnost')]
# [('companyName', '2. FVE HUMENNÉ')]
# [('companyName', '2.-0 LCA Consultants (Denmark)')]
# [('companyName', '2.13.61, Inc.')]
# [('companyName', '2.VMP')]
# [('companyName', '20/20 GeneSystem (United States)')]
# [('companyName', '2000 Flushes')]
# [('companyName', '2001 Outlet')]
# [('companyName', '2006 Minato Ward elevator accident')]
# [('companyName', '2012 in K-1 Events')]
# [('companyName', '2015, Inc.')]
# [('companyName', '2019 General Motors strike')]
# [('companyName', '20th Century Studios Home Entertainment'), ('OwnedBy', 'The Walt Disney Company'), ('obj3', 'http://www.wikidata.org/entity/Q7414'), ('Parent', 'Walt Disney Studios Home Entertainment')]
# [('companyName', '20th Century Studios Home Entertainment'), ('OwnedBy', 'Walt Disney Direct-to-Consumer & International'), ('obj3', 'http://www.wikidata.org/entity/Q54958626'), ('Parent', 'Walt Disney Studios Home Entertainment')]
# [('companyName', '20th Television Animation'), ('OwnedBy', 'The Walt Disney Company'), ('obj3', 'http://www.wikidata.org/entity/Q7414'), ('Parent', 'Disney Television Studios')]
# [('companyName', '21 Dollars')]
# [('companyName', '21 Mediavision')]
# [('companyName', '21 Rocks LLC')]
# [('companyName', '21CSi (United States)')]
# [('companyName', '21LADY Co., Ltd.')]
# [('companyName', '21Vianet')]
# [('companyName', '21c Consultancy (United Kingdom)')]
# [('companyName', '21st Century Entertainment')]
# [('companyName', '21st Century Film Corporation')]
# [('companyName', '21st Century Insurance')]
# [('companyName', '21st Century Media'), ('Parent', 'Digital First Media')]
# [('companyName', '21st Century Medicine')]
# [('companyName', '21st Century Newspapers')]
# [('companyName', '21st Century Oncology (United States)')]
# [('companyName', '21st Century Systems (United States)')]
# [('companyName', '21st Century Technologies (United States)')]
# [('companyName', '21st Century Technology PLC')]
# [('companyName', '21st Century Therapeutics (United States)')]
# [('companyName', '220 Volt'), ('numEm', '900')]
# [('companyName', '223rd Flight Unit')]
# [('companyName', '22nd Century Group (United States)')]
# [('companyName', '22nd Century Media')]
# [('companyName', '22squared')]
# [('companyName', '23 Studios')]
# [('companyName', '23andMe'), ('numEm', '683')]
# [('companyName', '23mofang Co., Ltd')]
# [('companyName', '24 Development')]
# [('companyName', '24 Frames Factory')]
# [('companyName', '24 Hour Fitness'), ('OwnedBy', 'AEA Investors'), ('obj3', 'http://www.wikidata.org/entity/Q4651259')]
# [('companyName', '24-Autobahn-Raststätten')]
# [('companyName', '24/7 Real Media')]
# [('companyName', '24/7 media')]
# [('companyName', '247 Music')]
# [('companyName', '247.sk')]
# [('companyName', '247Solar Plant (United States)')]
# [('companyName', '24M (United States)')]
# [('companyName', '25syv'), ('numEm', '50')]
# [('companyName', '290 Square Meters')]
# [('companyName', '2929 Entertainment'), ('OwnedBy', 'Todd Wagner'), ('obj3', 'http://www.wikidata.org/entity/Q7812693')]
# [('companyName', '2B Technologies (United States)')]
# [('companyName', '2BIG')]
# [('companyName', '2BrightSparks')]
# [('companyName', '2CRSI Group')]
# [('companyName', '2D Boy')]
# [('companyName', '2D Fab (Sweden)')]
# [('companyName', '2DHeat (United Kingdom)')]
# [('companyName', '2EL (Czechia)')]
# [('companyName', '2F Conseil'), ('OwnedBy', 'François Fillon'), ('obj3', 'http://www.wikidata.org/entity/Q101410')]
# [('companyName', '2F-Spiele')]
# [('companyName', '2G')]
# [('companyName', '2G Energy')]
# [('companyName', '2GO')]
# [('companyName', '2GO Group')]
# [('companyName', '2HP Production')]
# [('companyName', '2K Czech'), ('numEm', '110'), ('OwnedBy', 'Kush Games'), ('obj3', 'http://www.wikidata.org/entity/Q1136222'), ('Parent', '2K Games')]
# [('companyName', '2K Tools')]
# [('companyName', '2M Group')]
# [('companyName', '2N Telekomunikace')]
# [('companyName', '2P')]
# [('companyName', '2P Commercial Agency')]
# [('companyName', '2P-Info (Poland)')]
# [('companyName', '2PCS Solutions GmbH')]
# [('companyName', '2Spot Communications')]
# [('companyName', '2Trace')]
# [('companyName', '2Traders CZ')]
# [('companyName', '2U')]
# [('companyName', '2VV')]
# [('companyName', '2Wire')]
# [('companyName', '2XL Games')]
# [('companyName', '2b.creative')]
# [('companyName', '2degrees')]
# [('companyName', '2ergo')]
# [('companyName', '2friends pack')]
# [('companyName', '2i Industrial Informatics (Germany)')]
# [('companyName', '2i Rete Gas'), ('Parent', 'F2i Fondi Italiani per le Infrastrutture')]
# [('companyName', '2iC (United Kingdom)')]
# [('companyName', '2nd STREET')]
# [('companyName', '2ndQuadrant')]
# [('companyName', '2si')]
# [('companyName', '2the Max')]
# [('companyName', '2waytraffic'), ('OwnedBy', 'Sony Pictures'), ('obj3', 'http://www.wikidata.org/entity/Q822314')]
# [('companyName', '2wink')]
# [('companyName', '3'), ('OwnedBy', 'Investor AB'), ('obj3', 'http://www.wikidata.org/entity/Q1671804'), ('Parent', 'Investor AB')]
# [('companyName', '3'), ('OwnedBy', 'Investor AB'), ('obj3', 'http://www.wikidata.org/entity/Q1671804'), ('Parent', 'CK Hutchison Holdings')]
# [('companyName', '3'), ('OwnedBy', 'Investor AB'), ('obj3', 'http://www.wikidata.org/entity/Q1671804'), ('Parent', 'Hutchison Whampoa')]
# [('companyName', '3'), ('OwnedBy', 'CK Hutchison Holdings'), ('obj3', 'http://www.wikidata.org/entity/Q19548352'), ('Parent', 'Investor AB')]
# [('companyName', '3'), ('OwnedBy', 'CK Hutchison Holdings'), ('obj3', 'http://www.wikidata.org/entity/Q19548352'), ('Parent', 'CK Hutchison Holdings')]
# [('companyName', '3'), ('OwnedBy', 'CK Hutchison Holdings'), ('obj3', 'http://www.wikidata.org/entity/Q19548352'), ('Parent', 'Hutchison Whampoa')]
# [('companyName', '3'), ('OwnedBy', 'Hutchison Whampoa'), ('obj3', 'http://www.wikidata.org/entity/Q15805'), ('Parent', 'Investor AB')]
# [('companyName', '3'), ('OwnedBy', 'Hutchison Whampoa'), ('obj3', 'http://www.wikidata.org/entity/Q15805'), ('Parent', 'CK Hutchison Holdings')]
# [('companyName', '3'), ('OwnedBy', 'Hutchison Whampoa'), ('obj3', 'http://www.wikidata.org/entity/Q15805'), ('Parent', 'Hutchison Whampoa')]
# [('companyName', '3 Brewers')]
# [('companyName', '3 Coins')]
# [('companyName', '3 E Praha Engineering')]
# [('companyName', '3 Energy')]
# [('companyName', '3 Italy'), ('OwnedBy', 'Hutchison Whampoa'), ('obj3', 'http://www.wikidata.org/entity/Q15805'), ('Parent', '3')]
# [('companyName', '3 P')]
# [('companyName', '3 Pagen Versand und Handelsgesellschaft'), ('numEm', '530')]
# [('companyName', '3 Plus Group AG')]
# [('companyName', '3 Skypephone Series')]
# [('companyName', '3 Sprockets')]
# [('companyName', '3 Suisses')]
# [('companyName', '3 in one')]
# [('companyName', '3-D Matrix (Japan)')]
# [('companyName', '3-Sci (United Kingdom)')]
# [('companyName', '3-Sigma Research (United States)')]
# [('companyName', '3. Princova')]
# [('companyName', '307 International')]
# [('companyName', '3070')]
# [('companyName', '31 Degrees (France)')]
# [('companyName', '321 Studios')]
# [('companyName', '32Red')]
# [('companyName', '3541 PRG'), ('OwnedBy', 'HR GLL Europe Holding'), ('obj3', 'http://www.wikidata.org/entity/Q61791566')]
# [('companyName', '357 Sp. z o.o.')]
# [('companyName', '358 (Finland)')]
# [('companyName', '36,6'), ('numEm', '5000')]
# [('companyName', '360 Cities')]
# [('companyName', '360Learning')]
# [('companyName', '360T')]
# [('companyName', '360i')]
# [('companyName', '360networks')]
# [('companyName', '360pi (Canada)')]
# [('companyName', '360voice')]
# [('companyName', '361˚')]
# [('companyName', '365')]
# [('companyName', '365. world o.p.f.')]
# [('companyName', '365.bank'), ('OwnedBy', 'J&T Finance Group'), ('obj3', 'http://www.wikidata.org/entity/Q20120422')]
# [('companyName', '365.fintech')]
# [('companyName', '37001.cz')]
# [('companyName', '37Games')]
# [('companyName', '3801 Limited')]
# [('companyName', '39Drug')]
# [('companyName', '3A Composites')]
# [('companyName', '3B - The Fiberglass Company')]
# [('companyName', '3Bar Biologics (United States)')]
# [('companyName', '3Brain (Switzerland)')]
# [('companyName', '3C Cattle Feeders (United States)')]
# [('companyName', '3C Institute')]
# [('companyName', '3C Research (United Kingdom)')]
# [('companyName', '3CON Anlagenbau GmbH')]
# [('companyName', '3CX')]
# [('companyName', '3Com'), ('numEm', '6000'), ('OwnedBy', 'Hewlett Packard Enterprise'), ('obj3', 'http://www.wikidata.org/entity/Q19923099'), ('Parent', 'Aruba Networks')]
# [('companyName', '3D Biomatrix (United States)')]
# [('companyName', '3D Bioprinting Solutions (Russia)')]
# [('companyName', '3D ESTATE')]
# [('companyName', '3D Engineering Design (United Kingdom)')]
# [('companyName', '3D Glass Solutions (United States)')]
# [('companyName', '3D Industries (United Kingdom)')]
# [('companyName', '3D Molecular Designs (United States)')]
# [('companyName', '3D Realms')]
# [('companyName', '3D Realms Iogo')]
# [('companyName', '3D Reid (United Kingdom)')]
# [('companyName', '3D Robotics'), ('numEm', '350')]
# [('companyName', '3D Systems')]
# [('companyName', '3D Systems (Belgium)')]
# [('companyName', '3D Systems (United Kingdom)')]
# [('companyName', '3D Technology Laboratories (United States)')]
# [('companyName', '3D Visions')]
# [('companyName', '3D-Micromac (Germany)')]
# [('companyName', '3DFLOW')]
# [('companyName', '3DP')]
# [('companyName', '3DT Holdings (United States)')]
# [('companyName', '3DX-Ray (United Kingdom)')]
# [('companyName', '3Dconnexion')]
# [('companyName', '3Dim Laboratory')]
# [('companyName', '3Dlabs')]
# [('companyName', '3Dsolve')]
# [('companyName', '3Dwiser')]
# [('companyName', '3E (Belgium)')]
# [('companyName', '3E PROJEKT')]
# [('companyName', '3EFFE & D FINANCING')]
# [('companyName', '3Eflow (Sweden)')]
# [('companyName', '3F (United States)')]
# [('companyName', '3G Capital'), ('OwnedBy', 'Jorge Paulo Lemann'), ('obj3', 'http://www.wikidata.org/entity/Q122286')]
# [('companyName', '3G Consulting Engineers')]
# [('companyName', '3GIS')]
# [('companyName', '3GSolar (Norway)')]
# [('companyName', '3H Biomedical')]
# [('companyName', '3K Battery')]
# [('companyName', '3K GROUNDBREAKING')]
# [('companyName', '3K Partners')]
# [('companyName', '3LHD')]
# [('companyName', '3M (France)'), ('Parent', '3M')]
# [('companyName', '3M (Germany)'), ('Parent', '3M')]
# [('companyName', '3M (United Kingdom)'), ('Parent', '3M')]
# [('companyName', '3M Innovative Properties'), ('Parent', '3M')]
# [('companyName', '3M Japan')]
# [('companyName', '3M Technical Ceramics'), ('numEm', '626')]
# [('companyName', '3M Česko')]
# [('companyName', '3P Geotechnik ZT GmbH')]
# [('companyName', '3P-CHEM')]
# [('companyName', '3PD, Inc.'), ('Parent', 'Arcapita')]
# [('companyName', '3Q Group')]
# [('companyName', '3R Agrocarbon (Hungary)')]
# [('companyName', '3Roam')]
# [('companyName', '3S Photonics (France)')]
# [('companyName', '3S Sedlak')]
# [('companyName', '3S.cz')]
# [('companyName', '3SBio')]
# [('companyName', '3Scan')]
# [('companyName', '3Shape'), ('OwnedBy', '3SHAPE HOLDING'), ('obj3', 'http://www.wikidata.org/entity/Q51453159'), ('Parent', '3SHAPE HOLDING')]
# [('companyName', '3SixtyMedia'), ('OwnedBy', 'ITV Studios'), ('obj3', 'http://www.wikidata.org/entity/Q5975134')]
# [('companyName', '3T Cycling')]
# [('companyName', '3T RPD (United Kingdom)')]
# [('companyName', '3TEX (United States)')]
# [('companyName', '3TS Capital Partners')]
# [('companyName', '3V & H')]
# [('companyName', '3V Sigma (Italy)')]
# [('companyName', '3a Czech')]
# [('companyName', '3ality Technica')]
# [('companyName', '3d Scanners (United Kingdom)')]
# [('companyName', '3dMD (United Kingdom)')]
# [('companyName', '3dVirtuálníObchody')]
# [('companyName', '3dcart')]
# [('companyName', '3dfx Interactive'), ('Parent', 'Nvidia')]
# [('companyName', '3dvia')]
# [('companyName', '3dychy.pl')]
# [('companyName', '3e Œil Productions')]
# [('companyName', '3i Infotech Limited')]
# [('companyName', '3i Infrastructure')]
# [('companyName', '3i Property')]
# [('companyName', '3rd Generation Partnership Project')]
# [('companyName', '3rd Ward Brooklyn')]
# [('companyName', '3scale')]
# [('companyName', '3tera')]
# [('companyName', '3v Geomatics (Canada)')]
# [('companyName', '3ware')]
# [('companyName', '4 Digital Group')]
# [('companyName', '4 Gimel Investments SICAV')]
# [('companyName', '4 Investment.cz')]
# [('companyName', '4 June Rolling Stock Works')]
# [('companyName', '4 Lions Films')]
# [('companyName', '4-Legs')]
# [('companyName', '4-Real Intermedia GmbH')]
# [('companyName', '4-les')]
# [('companyName', '4. Zajištěný otevřený podílový fond ČP INVEST investiční společnost')]
# [('companyName', '40/40 Club'), ('OwnedBy', 'JAY-Z'), ('obj3', 'http://www.wikidata.org/entity/Q62766')]
# [('companyName', '407 ETR Concession Company Limited'), ('Parent', '407 International Inc')]
# [('companyName', '407 International Inc'), ('OwnedBy', 'OMERS'), ('obj3', 'http://www.wikidata.org/entity/Q3347600')]
# [('companyName', '407 International Inc'), ('OwnedBy', 'Ferrovial'), ('obj3', 'http://www.wikidata.org/entity/Q1408037')]
# [('companyName', '407 International Inc'), ('OwnedBy', 'CPP Investment Board'), ('obj3', 'http://www.wikidata.org/entity/Q5013693')]
# [('companyName', '407 International Inc'), ('OwnedBy', 'SNC-Lavalin'), ('obj3', 'http://www.wikidata.org/entity/Q944608')]
# [('companyName', '411 PAIN')]
# [('companyName', '42 Entertainment')]
# [('companyName', '42 Financial Services')]
# [('companyName', '42 Technology (United Kingdom)')]
# [('companyName', '44 Blue Productions')]
# [('companyName', '451 Research')]
# [('companyName', '451 Research (United Kingdom)')]
# [('companyName', '454 Life Sciences')]
# [('companyName', '47 Street')]
# [('companyName', '480 Biomedical (United States)')]
# [('companyName', '490 BioTech (United States)')]
# [('companyName', '495 Communications')]
# [('companyName', '49Games')]
# [('companyName', '4ALL IT spol.')]
# [('companyName', '4BIZ B2B')]
# [('companyName', '4C Air (United States)')]
# [('companyName', '4C Strategies (Sweden)')]
# [('companyName', "4C's CO , Ltd.")]
# [('companyName', '4Cs Breeding Technologies (United States)')]
# [('companyName', '4D (United Kingdom)')]
# [('companyName', '4D Pharma')]
# [('companyName', '4D Soft (Hungary)')]
# [('companyName', '4D Systems Pty Ltd')]
# [('companyName', '4D Technology (United States)')]
# [('companyName', '4ENERGY')]
# [('companyName', '4EVER')]
# [('companyName', '4ExBiz')]
# [('companyName', '4F')]
# [('companyName', '4FRNT Skis')]
# [('companyName', '4Frontiers Corporation')]
# [('companyName', '4Fun Media')]
# [('companyName', '4Fund'), ('OwnedBy', 'Pavla Bečková'), ('obj3', 'http://www.wikidata.org/entity/Q94454777')]
# [('companyName', '4Fund'), ('OwnedBy', 'MBMS'), ('obj3', 'http://www.wikidata.org/entity/Q94454975')]
# [('companyName', '4H Consulting')]
# [('companyName', '4ISP')]
# [('companyName', '4IT I (Sweden)')]
# [('companyName', '4K KNDNS')]
# [('companyName', '4Kids Home Video')]
# [('companyName', '4M')]
# [('companyName', '4M SYSTEMS')]
# [('companyName', '4Mobility')]
# [('companyName', '4Ocean')]
# [('companyName', '4P - Immo. Praha')]
# [('companyName', '4P Rube Göttingen'), ('Parent', 'Unilever')]
# [('companyName', '4Power (United States)')]
# [('companyName', '4S Production'), ('OwnedBy', 'Voice of Prague'), ('obj3', 'http://www.wikidata.org/entity/Q52637781')]
# [('companyName', '4Science')]
# [('companyName', '4Subsea (Norway)')]
# [('companyName', '4ThePlayer.com')]
# [('companyName', '4Videosoft Studio')]
# [('companyName', '4Y2')]
# [('companyName', '4YOU Airlines')]
# [('companyName', '4a Architekten')]
# [('companyName', '4cabling')]
# [('companyName', '4check')]
# [('companyName', '4human'), ('numEm', '80')]
# [('companyName', '4imprint plc')]
# [('companyName', '4ka'), ('OwnedBy', 'swan'), ('obj3', 'http://www.wikidata.org/entity/Q34384')]
# [('companyName', '4ka'), ('OwnedBy', 'Slovenská pošta'), ('obj3', 'http://www.wikidata.org/entity/Q1191849')]
# [('companyName', '4moms')]
# [('companyName', '5 PLUS CORPORATION')]
# [('companyName', '5-7-9')]
# [('companyName', '5-D Systems (United States)')]
# [('companyName', '50 c/s Group'), ('OwnedBy', 'Matériel de traction électrique'), ('obj3', 'http://www.wikidata.org/entity/Q3300038')]
# [('companyName', '50 c/s Group'), ('OwnedBy', 'Siemens'), ('obj3', 'http://www.wikidata.org/entity/Q81230')]
# [('companyName', '50 c/s Group'), ('OwnedBy', 'Maschinenfabrik Oerlikon'), ('obj3', 'http://www.wikidata.org/entity/Q1906878')]
# [('companyName', '50 c/s Group'), ('OwnedBy', 'AEG'), ('obj3', 'http://www.wikidata.org/entity/Q158276')]
# 500

# %% [markdown]
# It worked. So I can include the other properties. Test Blackberry

# %%
queryString = """
SELECT DISTINCT (?obj1 AS ?Num_Asset) (?obj2 AS ?num_Employees) (?obj5 AS ?est_value) (?obj6 AS ?net_profit) (?obj7 AS ?tot_rev) (?ownby AS ?OwnedBy )(?parentO AS ?Parent) 
WHERE { 


OPTIONAL {wd:Q502121 wdt:P4103 ?obj1 .} #num Asset
OPTIONAL {wd:Q502121 wdt:P1128 ?obj2 .} #num employees
OPTIONAL {wd:Q502121 wdt:P127 ?obj3 . #owned by
            # ?obj3 <http://schema.org/name> ?ownby .}
OPTIONAL {wd:Q502121 wdt:P749 ?obj4 . #parent organization
            # ?obj4 <http://schema.org/name> ?parentO .}
OPTIONAL {wd:Q502121 wdt:P8340 ?obj5 .} #est value

OPTIONAL {wd:Q502121 wdt:P2295 ?obj6 .} #net profit

OPTIONAL {wd:Q502121 wdt:P2139 ?obj7 .} #tot revenue
} 

LIMIT 500
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('num_Employees', '3647'), ('net_profit', '-152000000'), ('tot_rev', '1040000000')]
# 1

# %% [markdown]
# General BGP

# %%
queryString = """
SELECT DISTINCT ?cName (?obj1 AS ?Num_Asset) (?obj2 AS ?num_Employees) (?obj5 AS ?est_value) (?obj6 AS ?net_profit) (?obj7 AS ?tot_rev) (GROUP_CONCAT(DISTINCT ?ownby;separator='; ') AS ?OwnedBy )(?parentO AS ?Parent) 
WHERE { 

# ?company wdt:P31 wd:Q4830453  .

OPTIONAL {?company wdt:P4103 ?obj1 .} #num Asset
OPTIONAL {?company wdt:P1128 ?obj2 .} #num employees
OPTIONAL {?company wdt:P127 ?obj3 . #owned by
            # ?obj3 <http://schema.org/name> ?ownby .}
OPTIONAL {?company wdt:P749 ?obj4 . #parent organization
            # ?obj4 <http://schema.org/name> ?parentO .}
OPTIONAL {?company wdt:P8340 ?obj5 .} #est value

OPTIONAL {?company wdt:P2295 ?obj6 .} #net profit

OPTIONAL {?company wdt:P2139 ?obj7 .} #tot revenue

# ?company <http://schema.org/name> ?cName.
} 
ORDER BY DESC (?num_Employees)
LIMIT 50
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('cName', 'Walmart'), ('num_Employees', '2500000'), ('net_profit', '13643000000'), ('tot_rev', '559151000000'), ('OwnedBy', 'BlackRock; State Street Corporation; The Vanguard Group; Walton Enterprises')]
# [('cName', 'Amazon'), ('num_Employees', '1298000'), ('net_profit', '21300000000'), ('tot_rev', '386064000000'), ('OwnedBy', 'BlackRock; Jeff Bezos; The Vanguard Group')]
# [('cName', 'Foxconn'), ('num_Employees', '618460'), ('net_profit', '151357164000'), ('tot_rev', '4358733357000'), ('OwnedBy', 'Terry Gou; The Vanguard Group')]
# [('cName', 'PetroChina Company Limited'), ('num_Employees', '521566'), ('net_profit', '42098000000'), ('tot_rev', '1725428000000'), ('OwnedBy', 'China National Petroleum Corporation'), ('Parent', 'China National Petroleum Corporation')]
# [('cName', 'Siemens'), ('num_Employees', '372000'), ('net_profit', '5584000000'), ('tot_rev', '83000000000'), ('OwnedBy', 'BlackRock; Qatar Investment Authority; Siemens family; treasury stock')]
# [('cName', 'Rikushet'), ('num_Employees', 'nodeID://b70728'), ('OwnedBy', '')]
# [('cName', 'China National Petroleum Corporation'), ('num_Employees', '1589508'), ('net_profit', '56241880000'), ('tot_rev', '2599417420000'), ('OwnedBy', 'State-owned Assets Supervision and Administration Commission of the State Council')]
# [('cName', 'State Grid Corporation of China'), ('num_Employees', '1581000'), ('net_profit', '56509982428'), ('tot_rev', '2560254240000'), ('OwnedBy', 'State-owned Assets Supervision and Administration Commission of the State Council')]
# [('cName', 'Randstad N.V.'), ('num_Employees', '658580'), ('net_profit', '588200000'), ('tot_rev', '20684100000'), ('OwnedBy', 'ASR Nederland; Frits Goldschmeding; NN Group; Stichting Administratiekantoor Preferente Aandelen Randstad Holding')]
# [('cName', 'G4S'), ('num_Employees', '618260'), ('OwnedBy', '')]
# [('cName', 'RAO UES'), ('num_Employees', '577000'), ('tot_rev', '40377000000000'), ('OwnedBy', '')]
# [('cName', 'RAO UES'), ('num_Employees', '577000'), ('tot_rev', '18323400000'), ('OwnedBy', '')]
# [('cName', 'DHL'), ('num_Employees', '570000'), ('OwnedBy', ''), ('Parent', 'Deutsche Post AG')]
# [('cName', 'Deutsche Post AG'), ('num_Employees', '547459'), ('net_profit', '2224000000'), ('tot_rev', '66806000000'), ('OwnedBy', 'KfW')]
# [('cName', 'Volkswagen Group'), ('num_Employees', '513642'), ('net_profit', '5379000000'), ('tot_rev', '217267000000'), ('OwnedBy', 'Hannoversche Beteiligungsgesellschaft; Porsche Automobil Holding SE; Qatar Investment Authority')]
# [('cName', 'Agricultural Bank of China'), ('num_Employees', '503082'), ('net_profit', '180774000000'), ('tot_rev', '540862000000'), ('OwnedBy', 'Central Huijin Investment; Ministry of Finance; National Council for Social Security Fund')]
# [('cName', 'ISS A/S'), ('num_Employees', '471056'), ('net_profit', '3583000000'), ('tot_rev', '79137000000'), ('OwnedBy', 'Artisan Partners Asset Management; BlackRock; Kirkbi Invest')]
# [('cName', 'Gazprom'), ('num_Employees', '469600'), ('net_profit', '162407000000'), ('tot_rev', '6321559000000'), ('OwnedBy', 'Federal Agency for State Property Management; Rosneftegaz')]
# [('cName', 'Jardine Matheson'), ('num_Employees', '464000'), ('net_profit', '2840000000'), ('OwnedBy', '')]
# [('cName', 'Accenture'), ('num_Employees', '459000'), ('OwnedBy', '')]
# [('cName', 'India Post'), ('num_Employees', '448840'), ('net_profit', '-840000000'), ('tot_rev', '1800000000'), ('OwnedBy', 'Government of India'), ('Parent', 'Ministry of Communications')]
# [('cName', 'Industrial and Commercial Bank of China'), ('num_Employees', '439787'), ('net_profit', '317685000000'), ('tot_rev', '800075000000'), ('OwnedBy', 'Central Huijin Investment; Ministry of Finance')]
# [('cName', 'United Parcel Service'), ('num_Employees', '434000'), ('net_profit', '4910000000'), ('tot_rev', '65872000000'), ('OwnedBy', '')]
# [('cName', 'Tesco'), ('num_Employees', '423092'), ('net_profit', '129000000'), ('tot_rev', '54433000000'), ('OwnedBy', 'BlackRock; Deutsche Bank; Norges Bank; Schroders')]
# [('cName', 'Yum China'), ('num_Employees', '420000'), ('net_profit', '502000000'), ('tot_rev', '6622000000'), ('OwnedBy', 'Aberdeen Asset Management; BlackRock; Primavera Capital Group')]
# [('cName', 'Edeka'), ('num_Employees', '402000'), ('tot_rev', '61000000000'), ('OwnedBy', 'Edeka Minden-Hannover')]
# [('cName', 'R. J. Reynolds Tobacco Company'), ('num_Employees', '400000'), ('OwnedBy', 'Reynolds American'), ('Parent', 'Reynolds American')]
# [('cName', 'FedEx'), ('num_Employees', '400000'), ('net_profit', '2997000000'), ('tot_rev', '60319000000'), ('OwnedBy', '')]
# [('cName', 'SF Express'), ('num_Employees', '400000'), ('OwnedBy', '')]
# [('cName', 'The Home Depot'), ('num_Employees', '400000'), ('net_profit', '12490000000'), ('tot_rev', '125631000000'), ('OwnedBy', 'BlackRock; The Vanguard Group')]
# [('cName', 'Tata Consultancy Services'), ('num_Employees', '394998'), ('OwnedBy', 'Tata Group'), ('Parent', 'Tata Group')]
# [('cName', 'Samsung Electronics'), ('num_Employees', '392305'), ('net_profit', '22730000000000'), ('tot_rev', '201870000000000'), ('OwnedBy', 'Lee Kun-hee; National Pension Service; Samsung C&T Corporation; Samsung Life Insurance; treasury stock')]
# [('cName', 'Ukrainian Railways'), ('num_Employees', '375900'), ('OwnedBy', 'Ukraine')]
# [('cName', 'Ahold Delhaize'), ('num_Employees', '372000'), ('net_profit', '1793000000'), ('tot_rev', '62791000000'), ('OwnedBy', 'BlackRock; DeltaFort Beleggingen I; NN Group; Stichting Administratiekantoor Preferente Financieringsaandelen Ahold')]
# [('cName', 'Ping An Insurance'), ('num_Employees', '362035'), ('net_profit', '159359000000'), ('tot_rev', '1321418000000'), ('OwnedBy', 'Central Huijin Investment; Charoen Pokphand; Citigroup; JPMorgan Chase; Shenzhen Investment Holdings; UBS')]
# [('cName', 'Berkshire Hathaway'), ('num_Employees', '360000'), ('net_profit', '42521000000'), ('tot_rev', '245510000000'), ('OwnedBy', 'Bill Gates; Charlie Munger; David Gottesman; Fidelity Investments; Warren Buffett')]
# [('cName', 'Toyota'), ('num_Employees', '359542'), ('net_profit', '2312694000000'), ('tot_rev', '28403118000000'), ('OwnedBy', 'Nippon Life Insurance Company; Toyota Industries')]
# [('cName', 'IBM'), ('num_Employees', '352600'), ('net_profit', '11872000000'), ('tot_rev', '79590000000'), ('OwnedBy', 'Berkshire Hathaway; State Street Corporation; The Vanguard Group')]
# [('cName', 'Russian Post'), ('num_Employees', '351753'), ('net_profit', '1734000000'), ('tot_rev', '164800000000'), ('OwnedBy', 'Government of Russia'), ('Parent', 'Ministry of Digital Development, Communications and Mass Media of the Russian Federation')]
# [('cName', 'Sinopec'), ('num_Employees', '351019'), ('tot_rev', '2742779810000'), ('OwnedBy', 'China Petrochemical Corporation')]
# [('cName', 'X5 Retail Group'), ('num_Employees', '339716'), ('net_profit', '28344000000'), ('tot_rev', '1978026000000'), ('OwnedBy', '')]
# [('cName', 'Deloitte'), ('num_Employees', '334800'), ('tot_rev', '47600000000'), ('OwnedBy', '')]
# [('cName', 'Rosneft'), ('num_Employees', '334600'), ('net_profit', '181000000000'), ('tot_rev', '5757000000000'), ('OwnedBy', 'Government of Russia'), ('Parent', 'Rosneftegaz')]
# [('cName', 'Rosneft'), ('num_Employees', '334600'), ('net_profit', '181000000000'), ('tot_rev', '5757000000000'), ('OwnedBy', 'Government of Russia'), ('Parent', 'Federal Agency for State Property Management')]
# [('cName', 'Nestlé'), ('num_Employees', '328000'), ('net_profit', '9066000000'), ('tot_rev', '89800000000'), ('OwnedBy', 'BlackRock; Norges Bank Investment Management; treasury stock')]
# [('cName', 'Deutsche Bahn'), ('num_Employees', '315910'), ('tot_rev', '44200000000'), ('OwnedBy', 'Germany'), ('Parent', 'Germany')]
# [('cName', 'Bank of China'), ('num_Employees', '310042'), ('net_profit', '179417000000'), ('tot_rev', '473912000000'), ('OwnedBy', 'BlackRock; Central Huijin Investment; China Securities Finance Corp., Ltd.; National Council for Social Security Fund')]
# [('cName', 'China Telecommunications Corporation'), ('num_Employees', '309799'), ('tot_rev', '454492060000'), ('OwnedBy', "State Council of the People's Republic of China")]
# [('cName', 'China State Construction Engineering Corporation Limited'), ('num_Employees', '302827'), ('net_profit', '38241324000'), ('tot_rev', '1199324525000'), ('OwnedBy', 'Anbang Insurance Group; China Securities Finance Corp., Ltd.; China State Construction Engineering Corporation'), ('Parent', 'China State Construction Engineering Corporation')]
# [('cName', 'Auchan'), ('num_Employees', '302500'), ('net_profit', '3560000000'), ('tot_rev', '62400000000'), ('OwnedBy', ''), ('Parent', 'Association Familiale Mulliez')]
# 50

# %% [markdown]
# **Answer 1**
#
# The BGP to obtain the num of the employees and other numerical value is
#
# ```
# ?company wdt:P31 wd:Q4830453  .
#
# OPTIONAL {?company wdt:P4103 ?obj1 .} #num Asset
# OPTIONAL {?company wdt:P1128 ?obj2 .} #num employees
# OPTIONAL {?company wdt:P127 ?obj3 . #owned by
#             ?obj3 <http://schema.org/name> ?ownby .}
# OPTIONAL {?company wdt:P749 ?obj4 . #parent organization
#             ?obj4 <http://schema.org/name> ?parentO .}
# OPTIONAL {?company wdt:P8340 ?obj5 .} #est value
#
# OPTIONAL {?company wdt:P2295 ?obj6 .} #net profit
#
# OPTIONAL {?company wdt:P2139 ?obj7 .} #tot revenue
#
# ?company <http://schema.org/name> ?cName.
#
# ```

# %% [markdown]
# ----------------
#
# **2 - Identify the BGP to retrieve all companies owned by a company**
#
# Look to Blackberry and Disney

# %%
queryString = """
SELECT (?ownby AS ?OwnedBy )(?parentO AS ?Parent) ?obj5 (?ownerOf AS ?OwnerOf)
WHERE { 

wd:Q502121 wdt:P31 wd:Q4830453  . 

OPTIONAL {wd:Q502121 wdt:P127 ?obj3 . #owned by
            # ?obj3 <http://schema.org/name> ?ownBy .}
OPTIONAL {wd:Q502121 wdt:P749 ?obj4 . #parent organization
            # ?obj4 <http://schema.org/name> ?parentO .}
OPTIONAL {wd:Q502121 wdt:P1830 ?obj5 . #owner of
            # ?obj5 <http://schema.org/name> ?ownerOf .}

} 
LIMIT 50
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('obj5', 'http://www.wikidata.org/entity/Q84790062'), ('OwnerOf', 'BlackBerry')]
# 1

# %%
queryString = """
SELECT (?ownby AS ?OwnedBy )(?parentO AS ?Parent) (?ownerOf AS ?OwnerOf) ?obj5
WHERE {

wd:Q7414 wdt:P31 wd:Q4830453  . 

OPTIONAL {wd:Q7414 wdt:P127 ?obj3 . #owned by
            # ?obj3 <http://schema.org/name> ?ownBy .}
OPTIONAL {wd:Q7414 wdt:P749 ?obj4 . #parent organization
            # ?obj4 <http://schema.org/name> ?parentO .}
OPTIONAL {wd:Q7414 wdt:P1830 ?obj5 . #owner of
            # ?obj5 <http://schema.org/name> ?ownerOf .}

} 
LIMIT 50
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('OwnerOf', 'Club Penguin'), ('obj5', 'http://www.wikidata.org/entity/Q390223')]
# [('OwnerOf', 'YourTV'), ('obj5', 'http://www.wikidata.org/entity/Q22079560')]
# [('OwnerOf', 'Endemol Shine UK'), ('obj5', 'http://www.wikidata.org/entity/Q5376047')]
# [('OwnerOf', 'Walt Disney Television'), ('obj5', 'http://www.wikidata.org/entity/Q3565642')]
# [('OwnerOf', 'Disneyland'), ('obj5', 'http://www.wikidata.org/entity/Q181185')]
# [('OwnerOf', 'Beauty and the Beast'), ('obj5', 'http://www.wikidata.org/entity/Q16155122')]
# [('OwnerOf', 'Disney Channel Netherlands & Flanders'), ('obj5', 'http://www.wikidata.org/entity/Q2592540')]
# [('OwnerOf', '20,000 Leagues Under the Sea: Submarine Voyage'), ('obj5', 'http://www.wikidata.org/entity/Q2813838')]
# [('OwnerOf', 'Disney Theatrical Group'), ('obj5', 'http://www.wikidata.org/entity/Q4132994')]
# [('OwnerOf', 'Buena Vista International Television'), ('obj5', 'http://www.wikidata.org/entity/Q724613')]
# [('OwnerOf', 'Hotstar'), ('obj5', 'http://www.wikidata.org/entity/Q19758675')]
# [('OwnerOf', 'Alice in Wonderland'), ('obj5', 'http://www.wikidata.org/entity/Q17511049')]
# [('OwnerOf', 'Disney Interactive Studios'), ('obj5', 'http://www.wikidata.org/entity/Q1229035')]
# [('OwnerOf', 'LucasArts'), ('obj5', 'http://www.wikidata.org/entity/Q216611')]
# [('OwnerOf', 'Junction Point Studios'), ('obj5', 'http://www.wikidata.org/entity/Q3189994')]
# [('OwnerOf', 'Star TV'), ('obj5', 'http://www.wikidata.org/entity/Q130809')]
# [('OwnerOf', 'Walt Disney Pictures'), ('obj5', 'http://www.wikidata.org/entity/Q191224')]
# [('OwnerOf', 'ESPN Inc.'), ('obj5', 'http://www.wikidata.org/entity/Q17085515')]
# [('OwnerOf', 'Disney Channel'), ('obj5', 'http://www.wikidata.org/entity/Q178837')]
# [('OwnerOf', 'ImageMovers'), ('obj5', 'http://www.wikidata.org/entity/Q2405352')]
# [('OwnerOf', 'FX'), ('obj5', 'http://www.wikidata.org/entity/Q651228')]
# [('OwnerOf', 'Blue Sky Studios'), ('obj5', 'http://www.wikidata.org/entity/Q885885')]
# [('OwnerOf', 'Searchlight Pictures'), ('obj5', 'http://www.wikidata.org/entity/Q953040')]
# [('OwnerOf', 'Freeform'), ('obj5', 'http://www.wikidata.org/entity/Q287149')]
# [('OwnerOf', 'Industrial Light & Magic'), ('obj5', 'http://www.wikidata.org/entity/Q746676')]
# [('OwnerOf', 'Dimension Films'), ('obj5', 'http://www.wikidata.org/entity/Q908662')]
# [('OwnerOf', 'The Biography Channel'), ('obj5', 'http://www.wikidata.org/entity/Q622329')]
# [('OwnerOf', 'Disney Cinemagic'), ('obj5', 'http://www.wikidata.org/entity/Q635278')]
# [('OwnerOf', 'History'), ('obj5', 'http://www.wikidata.org/entity/Q1621107')]
# [('OwnerOf', 'The Muppets Studio'), ('obj5', 'http://www.wikidata.org/entity/Q3327964')]
# [('OwnerOf', 'Disney Press'), ('obj5', 'http://www.wikidata.org/entity/Q3030460')]
# [('OwnerOf', 'Rob Kidd'), ('obj5', 'http://www.wikidata.org/entity/Q7340286')]
# [('OwnerOf', 'Disneyland, Inc.'), ('obj5', 'http://www.wikidata.org/entity/Q3030499')]
# [('OwnerOf', 'Capital Disney'), ('obj5', 'http://www.wikidata.org/entity/Q2937387')]
# [('OwnerOf', 'Walt Disney Parks and Resorts U.S.'), ('obj5', 'http://www.wikidata.org/entity/Q3565637')]
# [('OwnerOf', 'The Walt Disney Company Italy'), ('obj5', 'http://www.wikidata.org/entity/Q3523275')]
# [('OwnerOf', 'Disney Character Voices International'), ('obj5', 'http://www.wikidata.org/entity/Q5282435')]
# [('OwnerOf', 'Black Rock Studio'), ('obj5', 'http://www.wikidata.org/entity/Q672664')]
# [('OwnerOf', 'Disney Music Group'), ('obj5', 'http://www.wikidata.org/entity/Q2104471')]
# [('OwnerOf', 'Pixar'), ('obj5', 'http://www.wikidata.org/entity/Q127552')]
# [('OwnerOf', 'American Broadcasting Company'), ('obj5', 'http://www.wikidata.org/entity/Q169889')]
# [('OwnerOf', 'Disney XD'), ('obj5', 'http://www.wikidata.org/entity/Q1858139')]
# [('OwnerOf', 'Disney XD'), ('obj5', 'http://www.wikidata.org/entity/Q2377604')]
# [('OwnerOf', 'Disney–ABC Domestic Television'), ('obj5', 'http://www.wikidata.org/entity/Q2737435')]
# [('OwnerOf', '20th Century Studios'), ('obj5', 'http://www.wikidata.org/entity/Q434841')]
# [('OwnerOf', 'Touchstone Pictures'), ('obj5', 'http://www.wikidata.org/entity/Q497155')]
# [('OwnerOf', 'Fox Studios Australia'), ('obj5', 'http://www.wikidata.org/entity/Q919514')]
# [('OwnerOf', '20th Century Fox Television'), ('obj5', 'http://www.wikidata.org/entity/Q2717612')]
# [('OwnerOf', 'Disney Cruise Line'), ('obj5', 'http://www.wikidata.org/entity/Q420947')]
# [('OwnerOf', 'Star Plus'), ('obj5', 'http://www.wikidata.org/entity/Q3631478')]
# 50

# %%
##LucasArts
queryString = """
SELECT (?ownby AS ?OwnedBy )(?parentO AS ?Parent) (?ownerOf AS ?OwnerOf) ?obj5
WHERE {

wd:Q216611 wdt:P31 ?p

OPTIONAL {wd:Q216611 wdt:P127 ?obj3 . #owned by
            # ?obj3 <http://schema.org/name> ?ownBy .}
OPTIONAL {wd:Q216611 wdt:P749 ?obj4 . #parent organization
            # ?obj4 <http://schema.org/name> ?parentO .}
OPTIONAL {wd:Q216611 wdt:P1830 ?obj5 . #owner of
            # ?obj5 <http://schema.org/name> ?ownerOf .}

} 
LIMIT 50
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('Parent', 'Lucasfilm')]
# [('Parent', 'Lucasfilm')]
# 2

# %% [markdown]
# If a company owns a company that owns others I would like to be able to retrive all sub-companies.
# Trying to count in this case Disney "owns" 345 company

# %%
queryString = """
SELECT COUNT(*)
WHERE {

wd:Q7414 wdt:P31 wd:Q4830453  . 
wd:Q7414 wdt:P1830* ?obj5 . #owner of

OPTIONAL{?obj5 wdt:P1830+ ?obj6 .}

} 
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('callret-0', '345')]
# 1

# %%
queryString = """
SELECT DISTINCT ?obj5 ?cName ?obj6 ?cName1
WHERE {

wd:Q7414 wdt:P31 wd:Q4830453  . 
wd:Q7414 wdt:P1830* ?obj5 . #owner of

# ?obj5 <http://schema.org/name> ?cName .

OPTIONAL{
# ?obj5 wdt:P1830+ ?obj6 .
# ?obj6 <http://schema.org/name> ?cName1 .
}

} 
ORDER BY ASC(?obj5)
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('obj5', 'http://www.wikidata.org/entity/Q10279075'), ('cName', 'Fox Movies')]
# [('obj5', 'http://www.wikidata.org/entity/Q1047009'), ('cName', 'Disney Store')]
# [('obj5', 'http://www.wikidata.org/entity/Q1047410'), ('cName', 'Walt Disney Animation Studios')]
# [('obj5', 'http://www.wikidata.org/entity/Q1052042'), ('cName', 'Epcot')]
# [('obj5', 'http://www.wikidata.org/entity/Q1118859'), ('cName', 'Fox Crime')]
# [('obj5', 'http://www.wikidata.org/entity/Q1141129'), ('cName', 'CrossGen')]
# [('obj5', 'http://www.wikidata.org/entity/Q11681754'), ('cName', 'FXX')]
# [('obj5', 'http://www.wikidata.org/entity/Q1169075'), ('cName', 'Lucasfilm Animation')]
# [('obj5', 'http://www.wikidata.org/entity/Q1189112'), ('cName', 'Nat Geo Music')]
# [('obj5', 'http://www.wikidata.org/entity/Q1200552'), ('cName', 'Marvel Entertainment')]
# [('obj5', 'http://www.wikidata.org/entity/Q1204077'), ('cName', 'ImageMovers')]
# [('obj5', 'http://www.wikidata.org/entity/Q1228987'), ('cName', 'Disney Digital 3-D')]
# [('obj5', 'http://www.wikidata.org/entity/Q1228989'), ('cName', 'Disney Dream')]
# [('obj5', 'http://www.wikidata.org/entity/Q1228992'), ('cName', 'Disney Fantasy')]
# [('obj5', 'http://www.wikidata.org/entity/Q1229035'), ('cName', 'Disney Interactive Studios')]
# [('obj5', 'http://www.wikidata.org/entity/Q1233073'), ('cName', 'Walt Disney Motion Pictures Group')]
# [('obj5', 'http://www.wikidata.org/entity/Q127552'), ('cName', 'Pixar')]
# [('obj5', 'http://www.wikidata.org/entity/Q130809'), ('cName', 'Star TV'), ('obj6', 'http://www.wikidata.org/entity/Q3046173'), ('cName1', 'ESPN Star Sports')]
# [('obj5', 'http://www.wikidata.org/entity/Q130809'), ('cName', 'Star TV'), ('obj6', 'http://www.wikidata.org/entity/Q306585'), ('cName1', 'Channel V')]
# [('obj5', 'http://www.wikidata.org/entity/Q130809'), ('cName', 'Star TV'), ('obj6', 'http://www.wikidata.org/entity/Q5072463'), ('cName1', 'Channel [V] Philippines')]
# [('obj5', 'http://www.wikidata.org/entity/Q1319610'), ('cName', 'Lifetime')]
# [('obj5', 'http://www.wikidata.org/entity/Q1348264'), ('cName', 'Hollywood Pictures')]
# [('obj5', 'http://www.wikidata.org/entity/Q138709'), ('cName', 'Nat Geo Wild')]
# [('obj5', 'http://www.wikidata.org/entity/Q1431781'), ('cName', 'Disney Parks, Experiences and Products'), ('obj6', 'http://www.wikidata.org/entity/Q1052042'), ('cName1', 'Epcot')]
# [('obj5', 'http://www.wikidata.org/entity/Q14928314'), ('cName', 'The Walt Disney Company Latin America')]
# [('obj5', 'http://www.wikidata.org/entity/Q15070400'), ('cName', "Mind's Eye Productions")]
# [('obj5', 'http://www.wikidata.org/entity/Q157118'), ('cName', 'National Geographic Channel'), ('obj6', 'http://www.wikidata.org/entity/Q138709'), ('cName1', 'Nat Geo Wild')]
# [('obj5', 'http://www.wikidata.org/entity/Q157118'), ('cName', 'National Geographic Channel'), ('obj6', 'http://www.wikidata.org/entity/Q3336288'), ('cName1', 'Nat Geo Wild')]
# [('obj5', 'http://www.wikidata.org/entity/Q157118'), ('cName', 'National Geographic Channel'), ('obj6', 'http://www.wikidata.org/entity/Q2299634'), ('cName1', 'National Geographic People')]
# [('obj5', 'http://www.wikidata.org/entity/Q15731902'), ('cName', 'Aladdin')]
# [('obj5', 'http://www.wikidata.org/entity/Q16155122'), ('cName', 'Beauty and the Beast')]
# [('obj5', 'http://www.wikidata.org/entity/Q1621107'), ('cName', 'History')]
# [('obj5', 'http://www.wikidata.org/entity/Q16271976'), ('cName', 'Movies OK')]
# [('obj5', 'http://www.wikidata.org/entity/Q16558744'), ('cName', 'ESPN 2 (Brasil)')]
# [('obj5', 'http://www.wikidata.org/entity/Q16679850'), ('cName', 'The Walt Disney Company Germany')]
# [('obj5', 'http://www.wikidata.org/entity/Q16683129'), ('cName', 'Walt Disney Internet Group')]
# [('obj5', 'http://www.wikidata.org/entity/Q16835471'), ('cName', 'Disney Junior Greece')]
# [('obj5', 'http://www.wikidata.org/entity/Q16911414'), ('cName', 'Grantland')]
# [('obj5', 'http://www.wikidata.org/entity/Q169889'), ('cName', 'American Broadcasting Company'), ('obj6', 'http://www.wikidata.org/entity/Q17085515'), ('cName1', 'ESPN Inc.')]
# [('obj5', 'http://www.wikidata.org/entity/Q169889'), ('cName', 'American Broadcasting Company'), ('obj6', 'http://www.wikidata.org/entity/Q287171'), ('cName1', 'ABC News')]
# [('obj5', 'http://www.wikidata.org/entity/Q169889'), ('cName', 'American Broadcasting Company'), ('obj6', 'http://www.wikidata.org/entity/Q51595207'), ('cName1', 'list of production companies owned by the American Broadcasting Company')]
# [('obj5', 'http://www.wikidata.org/entity/Q169889'), ('cName', 'American Broadcasting Company'), ('obj6', 'http://www.wikidata.org/entity/Q7426051'), ('cName1', 'Satellite News Channel')]
# [('obj5', 'http://www.wikidata.org/entity/Q169889'), ('cName', 'American Broadcasting Company'), ('obj6', 'http://www.wikidata.org/entity/Q7949486'), ('cName1', 'WFRO')]
# [('obj5', 'http://www.wikidata.org/entity/Q169889'), ('cName', 'American Broadcasting Company'), ('obj6', 'http://www.wikidata.org/entity/Q600669'), ('cName1', 'FiveThirtyEight')]
# [('obj5', 'http://www.wikidata.org/entity/Q16991842'), ('cName', 'Disney Junior Poland')]
# [('obj5', 'http://www.wikidata.org/entity/Q17014745'), ('cName', 'BabyZone.com')]
# [('obj5', 'http://www.wikidata.org/entity/Q17018738'), ('cName', 'Kingsman')]
# [('obj5', 'http://www.wikidata.org/entity/Q17070395'), ('cName', 'MyMagic+')]
# [('obj5', 'http://www.wikidata.org/entity/Q17082860'), ('cName', 'spoonful.com')]
# [('obj5', 'http://www.wikidata.org/entity/Q17085515'), ('cName', 'ESPN Inc.')]
# [('obj5', 'http://www.wikidata.org/entity/Q17145072'), ('cName', 'STAR World Premiere')]
# [('obj5', 'http://www.wikidata.org/entity/Q17183023'), ('cName', 'Radio Disney Group, LLC')]
# [('obj5', 'http://www.wikidata.org/entity/Q17511049'), ('cName', 'Alice in Wonderland')]
# [('obj5', 'http://www.wikidata.org/entity/Q17619901'), ('cName', 'Lifetime Latinoamérica')]
# [('obj5', 'http://www.wikidata.org/entity/Q17625387'), ('cName', 'Playhouse Disney (Spain)')]
# [('obj5', 'http://www.wikidata.org/entity/Q17639984'), ('cName', 'The Walt Disney Company Limited')]
# [('obj5', 'http://www.wikidata.org/entity/Q178837'), ('cName', 'Disney Channel')]
# [('obj5', 'http://www.wikidata.org/entity/Q17984894'), ('cName', 'Winnie the Pooh')]
# [('obj5', 'http://www.wikidata.org/entity/Q181185'), ('cName', 'Disneyland')]
# [('obj5', 'http://www.wikidata.org/entity/Q18148065'), ('cName', 'Frozen')]
# [('obj5', 'http://www.wikidata.org/entity/Q18149304'), ('cName', 'Disney Tsum Tsum')]
# [('obj5', 'http://www.wikidata.org/entity/Q18207757'), ('cName', 'STAR Sports 2')]
# [('obj5', 'http://www.wikidata.org/entity/Q1858139'), ('cName', 'Disney XD')]
# [('obj5', 'http://www.wikidata.org/entity/Q18636714'), ('cName', 'Disney utilidor system')]
# [('obj5', 'http://www.wikidata.org/entity/Q191224'), ('cName', 'Walt Disney Pictures'), ('obj6', 'http://www.wikidata.org/entity/Q15731902'), ('cName1', 'Aladdin')]
# [('obj5', 'http://www.wikidata.org/entity/Q191224'), ('cName', 'Walt Disney Pictures'), ('obj6', 'http://www.wikidata.org/entity/Q1047410'), ('cName1', 'Walt Disney Animation Studios')]
# [('obj5', 'http://www.wikidata.org/entity/Q191224'), ('cName', 'Walt Disney Pictures'), ('obj6', 'http://www.wikidata.org/entity/Q2081339'), ('cName1', 'Disneytoon Studios')]
# [('obj5', 'http://www.wikidata.org/entity/Q191224'), ('cName', 'Walt Disney Pictures'), ('obj6', 'http://www.wikidata.org/entity/Q2944088'), ('cName1', 'Pixar Canada')]
# [('obj5', 'http://www.wikidata.org/entity/Q191224'), ('cName', 'Walt Disney Pictures'), ('obj6', 'http://www.wikidata.org/entity/Q17984894'), ('cName1', 'Winnie the Pooh')]
# [('obj5', 'http://www.wikidata.org/entity/Q191224'), ('cName', 'Walt Disney Pictures'), ('obj6', 'http://www.wikidata.org/entity/Q27151437'), ('cName1', 'Walt Disney Animation Canada')]
# [('obj5', 'http://www.wikidata.org/entity/Q191224'), ('cName', 'Walt Disney Pictures'), ('obj6', 'http://www.wikidata.org/entity/Q3565599'), ('cName1', 'Walt Disney Animation France')]
# [('obj5', 'http://www.wikidata.org/entity/Q19758675'), ('cName', 'Hotstar')]
# [('obj5', 'http://www.wikidata.org/entity/Q19868095'), ('cName', 'Disney XD')]
# [('obj5', 'http://www.wikidata.org/entity/Q19878302'), ('cName', 'Transportation and Ticket Center')]
# [('obj5', 'http://www.wikidata.org/entity/Q198949'), ('cName', 'Disney Magic')]
# [('obj5', 'http://www.wikidata.org/entity/Q198957'), ('cName', 'Disney Wonder')]
# [('obj5', 'http://www.wikidata.org/entity/Q2014847'), ('cName', 'BabyTV')]
# [('obj5', 'http://www.wikidata.org/entity/Q2037777'), ('cName', 'Blip')]
# [('obj5', 'http://www.wikidata.org/entity/Q206521'), ('cName', 'Disneyland Paris')]
# [('obj5', 'http://www.wikidata.org/entity/Q206859'), ('cName', 'Walt Disney World Resort'), ('obj6', 'http://www.wikidata.org/entity/Q17070395'), ('cName1', 'MyMagic+')]
# [('obj5', 'http://www.wikidata.org/entity/Q206859'), ('cName', 'Walt Disney World Resort'), ('obj6', 'http://www.wikidata.org/entity/Q18636714'), ('cName1', 'Disney utilidor system')]
# [('obj5', 'http://www.wikidata.org/entity/Q206859'), ('cName', 'Walt Disney World Resort'), ('obj6', 'http://www.wikidata.org/entity/Q19878302'), ('cName1', 'Transportation and Ticket Center')]
# [('obj5', 'http://www.wikidata.org/entity/Q206859'), ('cName', 'Walt Disney World Resort'), ('obj6', 'http://www.wikidata.org/entity/Q22296075'), ('cName1', "Disney's Magical Express")]
# [('obj5', 'http://www.wikidata.org/entity/Q2081339'), ('cName', 'Disneytoon Studios')]
# [('obj5', 'http://www.wikidata.org/entity/Q2084961'), ('cName', '20th Century Studios Home Entertainment')]
# [('obj5', 'http://www.wikidata.org/entity/Q2104471'), ('cName', 'Disney Music Group')]
# [('obj5', 'http://www.wikidata.org/entity/Q2125296'), ('cName', 'Disney Springs')]
# [('obj5', 'http://www.wikidata.org/entity/Q216611'), ('cName', 'LucasArts')]
# [('obj5', 'http://www.wikidata.org/entity/Q217776'), ('cName', 'ESPN'), ('obj6', 'http://www.wikidata.org/entity/Q3046149'), ('cName1', 'ESPN Extra')]
# [('obj5', 'http://www.wikidata.org/entity/Q217776'), ('cName', 'ESPN'), ('obj6', 'http://www.wikidata.org/entity/Q3259110'), ('cName1', 'Longhorn Network')]
# [('obj5', 'http://www.wikidata.org/entity/Q217776'), ('cName', 'ESPN'), ('obj6', 'http://www.wikidata.org/entity/Q600669'), ('cName1', 'FiveThirtyEight')]
# [('obj5', 'http://www.wikidata.org/entity/Q217776'), ('cName', 'ESPN'), ('obj6', 'http://www.wikidata.org/entity/Q5324239'), ('cName1', 'ESPN Films')]
# [('obj5', 'http://www.wikidata.org/entity/Q217776'), ('cName', 'ESPN'), ('obj6', 'http://www.wikidata.org/entity/Q5434435'), ('cName1', 'Fanzter')]
# [('obj5', 'http://www.wikidata.org/entity/Q217776'), ('cName', 'ESPN'), ('obj6', 'http://www.wikidata.org/entity/Q3046137'), ('cName1', 'ESPN.com')]
# [('obj5', 'http://www.wikidata.org/entity/Q217776'), ('cName', 'ESPN'), ('obj6', 'http://www.wikidata.org/entity/Q3046181'), ('cName1', 'ESPN FC')]
# [('obj5', 'http://www.wikidata.org/entity/Q217776'), ('cName', 'ESPN'), ('obj6', 'http://www.wikidata.org/entity/Q16911414'), ('cName1', 'Grantland')]
# [('obj5', 'http://www.wikidata.org/entity/Q217776'), ('cName', 'ESPN'), ('obj6', 'http://www.wikidata.org/entity/Q2887818'), ('cName1', 'ESPN3')]
# [('obj5', 'http://www.wikidata.org/entity/Q217776'), ('cName', 'ESPN'), ('obj6', 'http://www.wikidata.org/entity/Q16558744'), ('cName1', 'ESPN 2 (Brasil)')]
# [('obj5', 'http://www.wikidata.org/entity/Q217776'), ('cName', 'ESPN'), ('obj6', 'http://www.wikidata.org/entity/Q5816263'), ('cName1', 'ESPN 2 (Andino)')]
# [('obj5', 'http://www.wikidata.org/entity/Q217776'), ('cName', 'ESPN'), ('obj6', 'http://www.wikidata.org/entity/Q5816271'), ('cName1', 'ESPN 3 (Latinoamérica)')]
# [('obj5', 'http://www.wikidata.org/entity/Q217776'), ('cName', 'ESPN'), ('obj6', 'http://www.wikidata.org/entity/Q6167975'), ('cName1', "Jayski's Silly Season Site")]
# [('obj5', 'http://www.wikidata.org/entity/Q217776'), ('cName', 'ESPN'), ('obj6', 'http://www.wikidata.org/entity/Q8771352'), ('cName1', 'ESPN+ (Latin America)')]
# [('obj5', 'http://www.wikidata.org/entity/Q22079532'), ('cName', 'The Walt Disney Company Argentina')]
# [('obj5', 'http://www.wikidata.org/entity/Q22079560'), ('cName', 'YourTV')]
# [('obj5', 'http://www.wikidata.org/entity/Q22092344'), ('cName', 'Star Wars')]
# [('obj5', 'http://www.wikidata.org/entity/Q2216535'), ('cName', 'Walt Disney Studios')]
# [('obj5', 'http://www.wikidata.org/entity/Q22296075'), ('cName', "Disney's Magical Express")]
# [('obj5', 'http://www.wikidata.org/entity/Q2260281'), ('cName', 'Disney Channel Italy')]
# [('obj5', 'http://www.wikidata.org/entity/Q2273453'), ('cName', 'STAR World')]
# [('obj5', 'http://www.wikidata.org/entity/Q2299634'), ('cName', 'National Geographic People')]
# [('obj5', 'http://www.wikidata.org/entity/Q23022746'), ('cName', 'Star Utsav Movies')]
# [('obj5', 'http://www.wikidata.org/entity/Q23022864'), ('cName', 'Viceland')]
# [('obj5', 'http://www.wikidata.org/entity/Q2340292'), ('cName', 'Euro Disney S.C.A.')]
# [('obj5', 'http://www.wikidata.org/entity/Q2376669'), ('cName', 'Disney Junior (Spain)')]
# [('obj5', 'http://www.wikidata.org/entity/Q2377604'), ('cName', 'Disney XD')]
# [('obj5', 'http://www.wikidata.org/entity/Q2378052'), ('cName', 'Disney Channel Spain')]
# [('obj5', 'http://www.wikidata.org/entity/Q23837644'), ('cName', 'Endemol Shine Group')]
# [('obj5', 'http://www.wikidata.org/entity/Q2405352'), ('cName', 'ImageMovers')]
# [('obj5', 'http://www.wikidata.org/entity/Q242446'), ('cName', 'Lucasfilm'), ('obj6', 'http://www.wikidata.org/entity/Q2562640'), ('cName1', 'Indiana Jones')]
# [('obj5', 'http://www.wikidata.org/entity/Q242446'), ('cName', 'Lucasfilm'), ('obj6', 'http://www.wikidata.org/entity/Q22092344'), ('cName1', 'Star Wars')]
# [('obj5', 'http://www.wikidata.org/entity/Q24273005'), ('cName', 'thewaltdisneycompany.com')]
# [('obj5', 'http://www.wikidata.org/entity/Q2501552'), ('cName', 'Disneynature')]
# [('obj5', 'http://www.wikidata.org/entity/Q25377492'), ('cName', 'The Walt Disney Company Australia')]
# [('obj5', 'http://www.wikidata.org/entity/Q25384903'), ('cName', 'The Walt Disney Company China')]
# [('obj5', 'http://www.wikidata.org/entity/Q2562640'), ('cName', 'Indiana Jones')]
# [('obj5', 'http://www.wikidata.org/entity/Q2592540'), ('cName', 'Disney Channel Netherlands & Flanders')]
# [('obj5', 'http://www.wikidata.org/entity/Q264058'), ('cName', 'H2')]
# [('obj5', 'http://www.wikidata.org/entity/Q2703822'), ('cName', 'Skywalker Sound')]
# [('obj5', 'http://www.wikidata.org/entity/Q27151437'), ('cName', 'Walt Disney Animation Canada')]
# [('obj5', 'http://www.wikidata.org/entity/Q2717612'), ('cName', '20th Century Fox Television')]
# [('obj5', 'http://www.wikidata.org/entity/Q27186707'), ('cName', 'Jumbo Pictures')]
# [('obj5', 'http://www.wikidata.org/entity/Q2734852'), ('cName', 'GMTV')]
# [('obj5', 'http://www.wikidata.org/entity/Q2737435'), ('cName', 'Disney–ABC Domestic Television')]
# [('obj5', 'http://www.wikidata.org/entity/Q277561'), ('cName', 'A&E')]
# [('obj5', 'http://www.wikidata.org/entity/Q2777866'), ('cName', 'DisneyQuest')]
# [('obj5', 'http://www.wikidata.org/entity/Q2813838'), ('cName', '20,000 Leagues Under the Sea: Submarine Voyage')]
# [('obj5', 'http://www.wikidata.org/entity/Q2814799'), ('cName', '20th Television')]
# [('obj5', 'http://www.wikidata.org/entity/Q28457298'), ('cName', 'FoxNext')]
# [('obj5', 'http://www.wikidata.org/entity/Q287149'), ('cName', 'Freeform')]
# [('obj5', 'http://www.wikidata.org/entity/Q287171'), ('cName', 'ABC News'), ('obj6', 'http://www.wikidata.org/entity/Q600669'), ('cName1', 'FiveThirtyEight')]
# [('obj5', 'http://www.wikidata.org/entity/Q2887818'), ('cName', 'ESPN3')]
# [('obj5', 'http://www.wikidata.org/entity/Q29015971'), ('cName', 'Disney Streaming Services')]
# [('obj5', 'http://www.wikidata.org/entity/Q2912731'), ('cName', 'Disney Channel (Israel)')]
# [('obj5', 'http://www.wikidata.org/entity/Q2915959'), ('cName', "Disney's River Country")]
# [('obj5', 'http://www.wikidata.org/entity/Q2937387'), ('cName', 'Capital Disney')]
# [('obj5', 'http://www.wikidata.org/entity/Q2944088'), ('cName', 'Pixar Canada')]
# [('obj5', 'http://www.wikidata.org/entity/Q2994210'), ('cName', 'STAR Sports 3')]
# [('obj5', 'http://www.wikidata.org/entity/Q3030351'), ('cName', 'Disney-ABC Cable Network Group')]
# [('obj5', 'http://www.wikidata.org/entity/Q3030368'), ('cName', 'Disney Channel')]
# [('obj5', 'http://www.wikidata.org/entity/Q3030369'), ('cName', 'Disney Channel')]
# [('obj5', 'http://www.wikidata.org/entity/Q3030374'), ('cName', 'Disney Channel Deutschland')]
# [('obj5', 'http://www.wikidata.org/entity/Q3030385'), ('cName', 'Disney Channel')]
# [('obj5', 'http://www.wikidata.org/entity/Q3030399'), ('cName', 'Disney Cinemagic')]
# [('obj5', 'http://www.wikidata.org/entity/Q3030405'), ('cName', 'Disney Direct')]
# [('obj5', 'http://www.wikidata.org/entity/Q3030406'), ('cName', 'Disney Development Company')]
# [('obj5', 'http://www.wikidata.org/entity/Q3030410'), ('cName', 'Disney Consumer Products')]
# [('obj5', 'http://www.wikidata.org/entity/Q3030411'), ('cName', 'Disney Editions')]
# [('obj5', 'http://www.wikidata.org/entity/Q3030429'), ('cName', 'Disney Institute')]
# [('obj5', 'http://www.wikidata.org/entity/Q3030432'), ('cName', 'Disney Interactive')]
# [('obj5', 'http://www.wikidata.org/entity/Q3030440'), ('cName', 'Disney Junior')]
# [('obj5', 'http://www.wikidata.org/entity/Q3030445'), ('cName', 'Disney Platform Distribution')]
# [('obj5', 'http://www.wikidata.org/entity/Q3030447'), ('cName', 'Disney Media Networks')]
# [('obj5', 'http://www.wikidata.org/entity/Q3030458'), ('cName', 'Disney Mobile')]
# [('obj5', 'http://www.wikidata.org/entity/Q3030460'), ('cName', 'Disney Press')]
# [('obj5', 'http://www.wikidata.org/entity/Q3030485'), ('cName', 'Disney Vacation Club')]
# [('obj5', 'http://www.wikidata.org/entity/Q3030499'), ('cName', 'Disneyland, Inc.')]
# [('obj5', 'http://www.wikidata.org/entity/Q3030506'), ('cName', 'Disneytown')]
# [('obj5', 'http://www.wikidata.org/entity/Q3030511'), ('cName', 'Disneyland Railroad')]
# [('obj5', 'http://www.wikidata.org/entity/Q3039254'), ('cName', 'Dream Quest Images')]
# [('obj5', 'http://www.wikidata.org/entity/Q3046137'), ('cName', 'ESPN.com')]
# [('obj5', 'http://www.wikidata.org/entity/Q3046149'), ('cName', 'ESPN Extra')]
# [('obj5', 'http://www.wikidata.org/entity/Q3046171'), ('cName', 'ESPN Zone')]
# [('obj5', 'http://www.wikidata.org/entity/Q3046173'), ('cName', 'ESPN Star Sports')]
# [('obj5', 'http://www.wikidata.org/entity/Q3046181'), ('cName', 'ESPN FC')]
# [('obj5', 'http://www.wikidata.org/entity/Q30492190'), ('cName', 'Nat Geo Kids (Latin America)')]
# [('obj5', 'http://www.wikidata.org/entity/Q30566378'), ('cName', 'A&E')]
# [('obj5', 'http://www.wikidata.org/entity/Q3064766'), ('cName', 'Fall Line Studios')]
# [('obj5', 'http://www.wikidata.org/entity/Q306585'), ('cName', 'Channel V')]
# [('obj5', 'http://www.wikidata.org/entity/Q30919172'), ('cName', 'History (Latinoamérica)')]
# [('obj5', 'http://www.wikidata.org/entity/Q3094998'), ('cName', 'Gamestar')]
# [('obj5', 'http://www.wikidata.org/entity/Q3100510'), ('cName', 'Hong Kong International Theme Parks')]
# [('obj5', 'http://www.wikidata.org/entity/Q313173'), ('cName', 'Toon Disney')]
# [('obj5', 'http://www.wikidata.org/entity/Q313621'), ('cName', 'Disney Junior')]
# [('obj5', 'http://www.wikidata.org/entity/Q3146319'), ('cName', 'Hotels of The Walt Disney Company')]
# [('obj5', 'http://www.wikidata.org/entity/Q3150108'), ('cName', 'Indiana Jones Adventure')]
# [('obj5', 'http://www.wikidata.org/entity/Q3150870'), ('cName', 'Infoseek')]
# [('obj5', 'http://www.wikidata.org/entity/Q3177799'), ('cName', 'Jetix Europe')]
# [('obj5', 'http://www.wikidata.org/entity/Q3177801'), ('cName', 'Jetix International')]
# [('obj5', 'http://www.wikidata.org/entity/Q3189915'), ('cName', 'Cartoon Pizza')]
# [('obj5', 'http://www.wikidata.org/entity/Q3189994'), ('cName', 'Junction Point Studios')]
# [('obj5', 'http://www.wikidata.org/entity/Q3191359'), ('cName', 'KESN')]
# [('obj5', 'http://www.wikidata.org/entity/Q3195479'), ('cName', 'Kerpoof')]
# [('obj5', 'http://www.wikidata.org/entity/Q3238409'), ('cName', 'Lifetime Entertainment Services')]
# [('obj5', 'http://www.wikidata.org/entity/Q3259110'), ('cName', 'Longhorn Network')]
# [('obj5', 'http://www.wikidata.org/entity/Q3282004'), ('cName', 'Tiger Aspect Productions')]
# [('obj5', 'http://www.wikidata.org/entity/Q32854807'), ('cName', 'Endemol Shine Iberia')]
# [('obj5', 'http://www.wikidata.org/entity/Q3299645'), ('cName', 'Disney Junior')]
# [('obj5', 'http://www.wikidata.org/entity/Q3327964'), ('cName', 'The Muppets Studio')]
# [('obj5', 'http://www.wikidata.org/entity/Q3336288'), ('cName', 'Nat Geo Wild')]
# [('obj5', 'http://www.wikidata.org/entity/Q334671'), ('cName', 'Disney Channel Scandinavia')]
# [('obj5', 'http://www.wikidata.org/entity/Q3366991'), ('cName', 'Partners Federal Credit Union')]
# [('obj5', 'http://www.wikidata.org/entity/Q3433822'), ('cName', 'Crime & Investigation Network')]
# [('obj5', 'http://www.wikidata.org/entity/Q3492330'), ('cName', 'Endemol Australia')]
# [('obj5', 'http://www.wikidata.org/entity/Q3497261'), ('cName', 'Starwave')]
# [('obj5', 'http://www.wikidata.org/entity/Q3497756'), ('cName', 'Steamboat Ventures')]
# [('obj5', 'http://www.wikidata.org/entity/Q3523270'), ('cName', 'The Walt Disney Company France')]
# [('obj5', 'http://www.wikidata.org/entity/Q3523271'), ('cName', 'The Walt Disney Company CIS')]
# [('obj5', 'http://www.wikidata.org/entity/Q3523272'), ('cName', 'The Walt Disney Company Southeast Asia')]
# [('obj5', 'http://www.wikidata.org/entity/Q3523273'), ('cName', 'The Walt Disney Company India')]
# [('obj5', 'http://www.wikidata.org/entity/Q3523275'), ('cName', 'The Walt Disney Company Italy')]
# [('obj5', 'http://www.wikidata.org/entity/Q3556742'), ('cName', 'Viajar')]
# [('obj5', 'http://www.wikidata.org/entity/Q3561108'), ('cName', 'Vista Federal Credit Union')]
# [('obj5', 'http://www.wikidata.org/entity/Q3564667'), ('cName', 'WEPN')]
# [('obj5', 'http://www.wikidata.org/entity/Q3564732'), ('cName', 'WMVP')]
# [('obj5', 'http://www.wikidata.org/entity/Q3565599'), ('cName', 'Walt Disney Animation France')]
# [('obj5', 'http://www.wikidata.org/entity/Q3565606'), ('cName', 'Disney Software')]
# [('obj5', 'http://www.wikidata.org/entity/Q3565607'), ('cName', 'Disney Educational Productions')]
# [('obj5', 'http://www.wikidata.org/entity/Q3565612'), ('cName', 'Walt Disney International')]
# [('obj5', 'http://www.wikidata.org/entity/Q3565620'), ('cName', 'Walt Disney Publications')]
# [('obj5', 'http://www.wikidata.org/entity/Q3565621'), ('cName', 'The Walt Disney Company (Japan)')]
# [('obj5', 'http://www.wikidata.org/entity/Q3565623'), ('cName', 'Walt Disney Music Company, Inc.')]
# [('obj5', 'http://www.wikidata.org/entity/Q3565635'), ('cName', 'Walt Disney World Casting Center')]
# [('obj5', 'http://www.wikidata.org/entity/Q3565637'), ('cName', 'Walt Disney Parks and Resorts U.S.')]
# [('obj5', 'http://www.wikidata.org/entity/Q3565642'), ('cName', 'Walt Disney Television')]
# [('obj5', 'http://www.wikidata.org/entity/Q3628946'), ('cName', 'Star Sports')]
# [('obj5', 'http://www.wikidata.org/entity/Q3630152'), ('cName', 'STAR Utsav')]
# [('obj5', 'http://www.wikidata.org/entity/Q3631478'), ('cName', 'Star Plus')]
# [('obj5', 'http://www.wikidata.org/entity/Q3631491'), ('cName', 'STAR Gold')]
# [('obj5', 'http://www.wikidata.org/entity/Q38072167'), ('cName', 'FX Movies (Latin America)')]
# [('obj5', 'http://www.wikidata.org/entity/Q390223'), ('cName', 'Club Penguin')]
# [('obj5', 'http://www.wikidata.org/entity/Q39058665'), ('cName', 'Star Bharat')]
# [('obj5', 'http://www.wikidata.org/entity/Q4132097'), ('cName', 'Military History')]
# [('obj5', 'http://www.wikidata.org/entity/Q4132994'), ('cName', 'Disney Theatrical Group')]
# [('obj5', 'http://www.wikidata.org/entity/Q420947'), ('cName', 'Disney Cruise Line'), ('obj6', 'http://www.wikidata.org/entity/Q1228989'), ('cName1', 'Disney Dream')]
# [('obj5', 'http://www.wikidata.org/entity/Q420947'), ('cName', 'Disney Cruise Line'), ('obj6', 'http://www.wikidata.org/entity/Q198949'), ('cName1', 'Disney Magic')]
# [('obj5', 'http://www.wikidata.org/entity/Q420947'), ('cName', 'Disney Cruise Line'), ('obj6', 'http://www.wikidata.org/entity/Q1228992'), ('cName1', 'Disney Fantasy')]
# [('obj5', 'http://www.wikidata.org/entity/Q420947'), ('cName', 'Disney Cruise Line'), ('obj6', 'http://www.wikidata.org/entity/Q198957'), ('cName1', 'Disney Wonder')]
# [('obj5', 'http://www.wikidata.org/entity/Q434841'), ('cName', '20th Century Studios'), ('obj6', 'http://www.wikidata.org/entity/Q17018738'), ('cName1', 'Kingsman')]
# [('obj5', 'http://www.wikidata.org/entity/Q45001184'), ('cName', 'National Geographic Kids Abu Dhabi')]
# [('obj5', 'http://www.wikidata.org/entity/Q465449'), ('cName', 'Miramax'), ('obj6', 'http://www.wikidata.org/entity/Q908662'), ('cName1', 'Dimension Films')]
# [('obj5', 'http://www.wikidata.org/entity/Q46996011'), ('cName', 'ESPN+')]
# [('obj5', 'http://www.wikidata.org/entity/Q47481944'), ('cName', 'Endemol Shine Israel')]
# [('obj5', 'http://www.wikidata.org/entity/Q4837590'), ('cName', 'babble.com')]
# [('obj5', 'http://www.wikidata.org/entity/Q49402184'), ('cName', 'Fox Movies')]
# [('obj5', 'http://www.wikidata.org/entity/Q4947547'), ('cName', 'Bossa Studios')]
# [('obj5', 'http://www.wikidata.org/entity/Q495107'), ('cName', 'Fox Life')]
# [('obj5', 'http://www.wikidata.org/entity/Q497155'), ('cName', 'Touchstone Pictures')]
# [('obj5', 'http://www.wikidata.org/entity/Q5072463'), ('cName', 'Channel [V] Philippines')]
# [('obj5', 'http://www.wikidata.org/entity/Q50991720'), ('cName', 'MovieCo')]
# [('obj5', 'http://www.wikidata.org/entity/Q51595207'), ('cName', 'list of production companies owned by the American Broadcasting Company')]
# [('obj5', 'http://www.wikidata.org/entity/Q5185160'), ('cName', 'Crime & Investigation Network')]
# [('obj5', 'http://www.wikidata.org/entity/Q5185161'), ('cName', 'Crime & Investigation Network Asia')]
# [('obj5', 'http://www.wikidata.org/entity/Q5270612'), ('cName', 'Fox Life India')]
# [('obj5', 'http://www.wikidata.org/entity/Q5282418'), ('cName', 'Disney Channel')]
# [('obj5', 'http://www.wikidata.org/entity/Q5282427'), ('cName', 'Disney Channel Malaysia')]
# [('obj5', 'http://www.wikidata.org/entity/Q5282435'), ('cName', 'Disney Character Voices International')]
# [('obj5', 'http://www.wikidata.org/entity/Q5282441'), ('cName', 'Disney D23')]
# [('obj5', 'http://www.wikidata.org/entity/Q5282458'), ('cName', 'Disney Junior')]
# [('obj5', 'http://www.wikidata.org/entity/Q5324239'), ('cName', 'ESPN Films')]
# [('obj5', 'http://www.wikidata.org/entity/Q5376047'), ('cName', 'Endemol Shine UK')]
# [('obj5', 'http://www.wikidata.org/entity/Q5427400'), ('cName', 'Fox Comedy Portugal')]
# [('obj5', 'http://www.wikidata.org/entity/Q5434435'), ('cName', 'Fanzter')]
# [('obj5', 'http://www.wikidata.org/entity/Q5476678'), ('cName', 'Fox Crime Asia')]
# [('obj5', 'http://www.wikidata.org/entity/Q5476702'), ('cName', 'Fox Filipino')]
# [('obj5', 'http://www.wikidata.org/entity/Q5476806'), ('cName', 'Fox Life Greece')]
# [('obj5', 'http://www.wikidata.org/entity/Q5476820'), ('cName', 'Fox Movie Channel')]
# [('obj5', 'http://www.wikidata.org/entity/Q5476840'), ('cName', 'Fox Movies Premium')]
# [('obj5', 'http://www.wikidata.org/entity/Q5476977'), ('cName', 'Fox Star Studios')]
# [('obj5', 'http://www.wikidata.org/entity/Q54857'), ('cName', 'Radio Disney')]
# [('obj5', 'http://www.wikidata.org/entity/Q55830205'), ('cName', 'Jetix CEE')]
# [('obj5', 'http://www.wikidata.org/entity/Q5816263'), ('cName', 'ESPN 2 (Andino)')]
# [('obj5', 'http://www.wikidata.org/entity/Q5816271'), ('cName', 'ESPN 3 (Latinoamérica)')]
# [('obj5', 'http://www.wikidata.org/entity/Q5930877'), ('cName', 'Jetix (Spain)')]
# [('obj5', 'http://www.wikidata.org/entity/Q600669'), ('cName', 'FiveThirtyEight')]
# [('obj5', 'http://www.wikidata.org/entity/Q6145466'), ('cName', 'The Walt Disney Company Iberia')]
# [('obj5', 'http://www.wikidata.org/entity/Q6148912'), ('cName', 'Toon Disney Spain')]
# [('obj5', 'http://www.wikidata.org/entity/Q6167975'), ('cName', "Jayski's Silly Season Site")]
# [('obj5', 'http://www.wikidata.org/entity/Q622329'), ('cName', 'The Biography Channel')]
# [('obj5', 'http://www.wikidata.org/entity/Q6310201'), ('cName', 'History TV18')]
# [('obj5', 'http://www.wikidata.org/entity/Q634019'), ('cName', '20th Century Animation')]
# [('obj5', 'http://www.wikidata.org/entity/Q635278'), ('cName', 'Disney Cinemagic')]
# [('obj5', 'http://www.wikidata.org/entity/Q637164'), ('cName', 'The Baby Einstein Company')]
# [('obj5', 'http://www.wikidata.org/entity/Q651228'), ('cName', 'FX')]
# [('obj5', 'http://www.wikidata.org/entity/Q654073'), ('cName', 'Walt Disney Television')]
# [('obj5', 'http://www.wikidata.org/entity/Q6545534'), ('cName', 'LMN')]
# [('obj5', 'http://www.wikidata.org/entity/Q672664'), ('cName', 'Black Rock Studio')]
# [('obj5', 'http://www.wikidata.org/entity/Q6739276'), ('cName', 'Disney Digital Network')]
# [('obj5', 'http://www.wikidata.org/entity/Q684994'), ('cName', 'Super RTL')]
# [('obj5', 'http://www.wikidata.org/entity/Q724613'), ('cName', 'Buena Vista International Television')]
# [('obj5', 'http://www.wikidata.org/entity/Q7280765'), ('cName', 'Radio Disney Brasil')]
# [('obj5', 'http://www.wikidata.org/entity/Q7340286'), ('cName', 'Rob Kidd')]
# [('obj5', 'http://www.wikidata.org/entity/Q738088'), ('cName', '24Kitchen')]
# [('obj5', 'http://www.wikidata.org/entity/Q7394683'), ('cName', 'STAR World India')]
# [('obj5', 'http://www.wikidata.org/entity/Q7394684'), ('cName', 'STAR World Philippines')]
# [('obj5', 'http://www.wikidata.org/entity/Q7414'), ('cName', 'The Walt Disney Company'), ('obj6', 'http://www.wikidata.org/entity/Q390223'), ('cName1', 'Club Penguin')]
# [('obj5', 'http://www.wikidata.org/entity/Q7414'), ('cName', 'The Walt Disney Company'), ('obj6', 'http://www.wikidata.org/entity/Q3046149'), ('cName1', 'ESPN Extra')]
# [('obj5', 'http://www.wikidata.org/entity/Q7414'), ('cName', 'The Walt Disney Company'), ('obj6', 'http://www.wikidata.org/entity/Q22079560'), ('cName1', 'YourTV')]
# [('obj5', 'http://www.wikidata.org/entity/Q7414'), ('cName', 'The Walt Disney Company'), ('obj6', 'http://www.wikidata.org/entity/Q5376047'), ('cName1', 'Endemol Shine UK')]
# [('obj5', 'http://www.wikidata.org/entity/Q7414'), ('cName', 'The Walt Disney Company'), ('obj6', 'http://www.wikidata.org/entity/Q3565642'), ('cName1', 'Walt Disney Television')]
# [('obj5', 'http://www.wikidata.org/entity/Q7414'), ('cName', 'The Walt Disney Company'), ('obj6', 'http://www.wikidata.org/entity/Q181185'), ('cName1', 'Disneyland')]
# [('obj5', 'http://www.wikidata.org/entity/Q7414'), ('cName', 'The Walt Disney Company'), ('obj6', 'http://www.wikidata.org/entity/Q16155122'), ('cName1', 'Beauty and the Beast')]
# [('obj5', 'http://www.wikidata.org/entity/Q7414'), ('cName', 'The Walt Disney Company'), ('obj6', 'http://www.wikidata.org/entity/Q2592540'), ('cName1', 'Disney Channel Netherlands & Flanders')]
# [('obj5', 'http://www.wikidata.org/entity/Q7414'), ('cName', 'The Walt Disney Company'), ('obj6', 'http://www.wikidata.org/entity/Q2813838'), ('cName1', '20,000 Leagues Under the Sea: Submarine Voyage')]
# [('obj5', 'http://www.wikidata.org/entity/Q7414'), ('cName', 'The Walt Disney Company'), ('obj6', 'http://www.wikidata.org/entity/Q4132994'), ('cName1', 'Disney Theatrical Group')]
# [('obj5', 'http://www.wikidata.org/entity/Q7414'), ('cName', 'The Walt Disney Company'), ('obj6', 'http://www.wikidata.org/entity/Q724613'), ('cName1', 'Buena Vista International Television')]
# [('obj5', 'http://www.wikidata.org/entity/Q7414'), ('cName', 'The Walt Disney Company'), ('obj6', 'http://www.wikidata.org/entity/Q19758675'), ('cName1', 'Hotstar')]
# [('obj5', 'http://www.wikidata.org/entity/Q7414'), ('cName', 'The Walt Disney Company'), ('obj6', 'http://www.wikidata.org/entity/Q17511049'), ('cName1', 'Alice in Wonderland')]
# [('obj5', 'http://www.wikidata.org/entity/Q7414'), ('cName', 'The Walt Disney Company'), ('obj6', 'http://www.wikidata.org/entity/Q1229035'), ('cName1', 'Disney Interactive Studios')]
# [('obj5', 'http://www.wikidata.org/entity/Q7414'), ('cName', 'The Walt Disney Company'), ('obj6', 'http://www.wikidata.org/entity/Q216611'), ('cName1', 'LucasArts')]
# [('obj5', 'http://www.wikidata.org/entity/Q7414'), ('cName', 'The Walt Disney Company'), ('obj6', 'http://www.wikidata.org/entity/Q3259110'), ('cName1', 'Longhorn Network')]
# [('obj5', 'http://www.wikidata.org/entity/Q7414'), ('cName', 'The Walt Disney Company'), ('obj6', 'http://www.wikidata.org/entity/Q3189994'), ('cName1', 'Junction Point Studios')]
# [('obj5', 'http://www.wikidata.org/entity/Q7414'), ('cName', 'The Walt Disney Company'), ('obj6', 'http://www.wikidata.org/entity/Q130809'), ('cName1', 'Star TV')]
# [('obj5', 'http://www.wikidata.org/entity/Q7414'), ('cName', 'The Walt Disney Company'), ('obj6', 'http://www.wikidata.org/entity/Q191224'), ('cName1', 'Walt Disney Pictures')]
# [('obj5', 'http://www.wikidata.org/entity/Q7414'), ('cName', 'The Walt Disney Company'), ('obj6', 'http://www.wikidata.org/entity/Q3046173'), ('cName1', 'ESPN Star Sports')]
# [('obj5', 'http://www.wikidata.org/entity/Q7414'), ('cName', 'The Walt Disney Company'), ('obj6', 'http://www.wikidata.org/entity/Q306585'), ('cName1', 'Channel V')]
# [('obj5', 'http://www.wikidata.org/entity/Q7414'), ('cName', 'The Walt Disney Company'), ('obj6', 'http://www.wikidata.org/entity/Q5072463'), ('cName1', 'Channel [V] Philippines')]
# [('obj5', 'http://www.wikidata.org/entity/Q7414'), ('cName', 'The Walt Disney Company'), ('obj6', 'http://www.wikidata.org/entity/Q17085515'), ('cName1', 'ESPN Inc.')]
# [('obj5', 'http://www.wikidata.org/entity/Q7414'), ('cName', 'The Walt Disney Company'), ('obj6', 'http://www.wikidata.org/entity/Q178837'), ('cName1', 'Disney Channel')]
# [('obj5', 'http://www.wikidata.org/entity/Q7414'), ('cName', 'The Walt Disney Company'), ('obj6', 'http://www.wikidata.org/entity/Q287171'), ('cName1', 'ABC News')]
# [('obj5', 'http://www.wikidata.org/entity/Q7414'), ('cName', 'The Walt Disney Company'), ('obj6', 'http://www.wikidata.org/entity/Q51595207'), ('cName1', 'list of production companies owned by the American Broadcasting Company')]
# [('obj5', 'http://www.wikidata.org/entity/Q7414'), ('cName', 'The Walt Disney Company'), ('obj6', 'http://www.wikidata.org/entity/Q7426051'), ('cName1', 'Satellite News Channel')]
# [('obj5', 'http://www.wikidata.org/entity/Q7414'), ('cName', 'The Walt Disney Company'), ('obj6', 'http://www.wikidata.org/entity/Q7949486'), ('cName1', 'WFRO')]
# [('obj5', 'http://www.wikidata.org/entity/Q7414'), ('cName', 'The Walt Disney Company'), ('obj6', 'http://www.wikidata.org/entity/Q2405352'), ('cName1', 'ImageMovers')]
# [('obj5', 'http://www.wikidata.org/entity/Q7414'), ('cName', 'The Walt Disney Company'), ('obj6', 'http://www.wikidata.org/entity/Q651228'), ('cName1', 'FX')]
# [('obj5', 'http://www.wikidata.org/entity/Q7414'), ('cName', 'The Walt Disney Company'), ('obj6', 'http://www.wikidata.org/entity/Q885885'), ('cName1', 'Blue Sky Studios')]
# [('obj5', 'http://www.wikidata.org/entity/Q7414'), ('cName', 'The Walt Disney Company'), ('obj6', 'http://www.wikidata.org/entity/Q953040'), ('cName1', 'Searchlight Pictures')]
# [('obj5', 'http://www.wikidata.org/entity/Q7414'), ('cName', 'The Walt Disney Company'), ('obj6', 'http://www.wikidata.org/entity/Q287149'), ('cName1', 'Freeform')]
# [('obj5', 'http://www.wikidata.org/entity/Q7414'), ('cName', 'The Walt Disney Company'), ('obj6', 'http://www.wikidata.org/entity/Q746676'), ('cName1', 'Industrial Light & Magic')]
# [('obj5', 'http://www.wikidata.org/entity/Q7414'), ('cName', 'The Walt Disney Company'), ('obj6', 'http://www.wikidata.org/entity/Q908662'), ('cName1', 'Dimension Films')]
# [('obj5', 'http://www.wikidata.org/entity/Q7414'), ('cName', 'The Walt Disney Company'), ('obj6', 'http://www.wikidata.org/entity/Q622329'), ('cName1', 'The Biography Channel')]
# [('obj5', 'http://www.wikidata.org/entity/Q7414'), ('cName', 'The Walt Disney Company'), ('obj6', 'http://www.wikidata.org/entity/Q635278'), ('cName1', 'Disney Cinemagic')]
# [('obj5', 'http://www.wikidata.org/entity/Q7414'), ('cName', 'The Walt Disney Company'), ('obj6', 'http://www.wikidata.org/entity/Q1621107'), ('cName1', 'History')]
# [('obj5', 'http://www.wikidata.org/entity/Q7414'), ('cName', 'The Walt Disney Company'), ('obj6', 'http://www.wikidata.org/entity/Q600669'), ('cName1', 'FiveThirtyEight')]
# [('obj5', 'http://www.wikidata.org/entity/Q7414'), ('cName', 'The Walt Disney Company'), ('obj6', 'http://www.wikidata.org/entity/Q3327964'), ('cName1', 'The Muppets Studio')]
# [('obj5', 'http://www.wikidata.org/entity/Q7414'), ('cName', 'The Walt Disney Company'), ('obj6', 'http://www.wikidata.org/entity/Q3030460'), ('cName1', 'Disney Press')]
# [('obj5', 'http://www.wikidata.org/entity/Q7414'), ('cName', 'The Walt Disney Company'), ('obj6', 'http://www.wikidata.org/entity/Q7340286'), ('cName1', 'Rob Kidd')]
# [('obj5', 'http://www.wikidata.org/entity/Q7414'), ('cName', 'The Walt Disney Company'), ('obj6', 'http://www.wikidata.org/entity/Q3030499'), ('cName1', 'Disneyland, Inc.')]
# [('obj5', 'http://www.wikidata.org/entity/Q7414'), ('cName', 'The Walt Disney Company'), ('obj6', 'http://www.wikidata.org/entity/Q2937387'), ('cName1', 'Capital Disney')]
# [('obj5', 'http://www.wikidata.org/entity/Q7414'), ('cName', 'The Walt Disney Company'), ('obj6', 'http://www.wikidata.org/entity/Q3565637'), ('cName1', 'Walt Disney Parks and Resorts U.S.')]
# [('obj5', 'http://www.wikidata.org/entity/Q7414'), ('cName', 'The Walt Disney Company'), ('obj6', 'http://www.wikidata.org/entity/Q1052042'), ('cName1', 'Epcot')]
# [('obj5', 'http://www.wikidata.org/entity/Q7414'), ('cName', 'The Walt Disney Company'), ('obj6', 'http://www.wikidata.org/entity/Q3523275'), ('cName1', 'The Walt Disney Company Italy')]
# [('obj5', 'http://www.wikidata.org/entity/Q7414'), ('cName', 'The Walt Disney Company'), ('obj6', 'http://www.wikidata.org/entity/Q5282435'), ('cName1', 'Disney Character Voices International')]
# [('obj5', 'http://www.wikidata.org/entity/Q7414'), ('cName', 'The Walt Disney Company'), ('obj6', 'http://www.wikidata.org/entity/Q672664'), ('cName1', 'Black Rock Studio')]
# [('obj5', 'http://www.wikidata.org/entity/Q7414'), ('cName', 'The Walt Disney Company'), ('obj6', 'http://www.wikidata.org/entity/Q17018738'), ('cName1', 'Kingsman')]
# [('obj5', 'http://www.wikidata.org/entity/Q7414'), ('cName', 'The Walt Disney Company'), ('obj6', 'http://www.wikidata.org/entity/Q2104471'), ('cName1', 'Disney Music Group')]
# [('obj5', 'http://www.wikidata.org/entity/Q7414'), ('cName', 'The Walt Disney Company'), ('obj6', 'http://www.wikidata.org/entity/Q127552'), ('cName1', 'Pixar')]
# [('obj5', 'http://www.wikidata.org/entity/Q7414'), ('cName', 'The Walt Disney Company'), ('obj6', 'http://www.wikidata.org/entity/Q169889'), ('cName1', 'American Broadcasting Company')]
# [('obj5', 'http://www.wikidata.org/entity/Q7414'), ('cName', 'The Walt Disney Company'), ('obj6', 'http://www.wikidata.org/entity/Q1858139'), ('cName1', 'Disney XD')]
# [('obj5', 'http://www.wikidata.org/entity/Q7414'), ('cName', 'The Walt Disney Company'), ('obj6', 'http://www.wikidata.org/entity/Q2377604'), ('cName1', 'Disney XD')]
# [('obj5', 'http://www.wikidata.org/entity/Q7414'), ('cName', 'The Walt Disney Company'), ('obj6', 'http://www.wikidata.org/entity/Q2737435'), ('cName1', 'Disney–ABC Domestic Television')]
# [('obj5', 'http://www.wikidata.org/entity/Q7414'), ('cName', 'The Walt Disney Company'), ('obj6', 'http://www.wikidata.org/entity/Q434841'), ('cName1', '20th Century Studios')]
# [('obj5', 'http://www.wikidata.org/entity/Q7414'), ('cName', 'The Walt Disney Company'), ('obj6', 'http://www.wikidata.org/entity/Q497155'), ('cName1', 'Touchstone Pictures')]
# [('obj5', 'http://www.wikidata.org/entity/Q7414'), ('cName', 'The Walt Disney Company'), ('obj6', 'http://www.wikidata.org/entity/Q2562640'), ('cName1', 'Indiana Jones')]
# [('obj5', 'http://www.wikidata.org/entity/Q7414'), ('cName', 'The Walt Disney Company'), ('obj6', 'http://www.wikidata.org/entity/Q919514'), ('cName1', 'Fox Studios Australia')]
# [('obj5', 'http://www.wikidata.org/entity/Q7414'), ('cName', 'The Walt Disney Company'), ('obj6', 'http://www.wikidata.org/entity/Q2717612'), ('cName1', '20th Century Fox Television')]
# [('obj5', 'http://www.wikidata.org/entity/Q7414'), ('cName', 'The Walt Disney Company'), ('obj6', 'http://www.wikidata.org/entity/Q1228989'), ('cName1', 'Disney Dream')]
# [('obj5', 'http://www.wikidata.org/entity/Q7414'), ('cName', 'The Walt Disney Company'), ('obj6', 'http://www.wikidata.org/entity/Q420947'), ('cName1', 'Disney Cruise Line')]
# [('obj5', 'http://www.wikidata.org/entity/Q7414'), ('cName', 'The Walt Disney Company'), ('obj6', 'http://www.wikidata.org/entity/Q3631478'), ('cName1', 'Star Plus')]
# [('obj5', 'http://www.wikidata.org/entity/Q7414'), ('cName', 'The Walt Disney Company'), ('obj6', 'http://www.wikidata.org/entity/Q2260281'), ('cName1', 'Disney Channel Italy')]
# [('obj5', 'http://www.wikidata.org/entity/Q7414'), ('cName', 'The Walt Disney Company'), ('obj6', 'http://www.wikidata.org/entity/Q5324239'), ('cName1', 'ESPN Films')]
# [('obj5', 'http://www.wikidata.org/entity/Q7414'), ('cName', 'The Walt Disney Company'), ('obj6', 'http://www.wikidata.org/entity/Q15731902'), ('cName1', 'Aladdin')]
# [('obj5', 'http://www.wikidata.org/entity/Q7414'), ('cName', 'The Walt Disney Company'), ('obj6', 'http://www.wikidata.org/entity/Q32854807'), ('cName1', 'Endemol Shine Iberia')]
# [('obj5', 'http://www.wikidata.org/entity/Q7414'), ('cName', 'The Walt Disney Company'), ('obj6', 'http://www.wikidata.org/entity/Q465449'), ('cName1', 'Miramax')]
# [('obj5', 'http://www.wikidata.org/entity/Q7414'), ('cName', 'The Walt Disney Company'), ('obj6', 'http://www.wikidata.org/entity/Q2814799'), ('cName1', '20th Television')]
# [('obj5', 'http://www.wikidata.org/entity/Q7414'), ('cName', 'The Walt Disney Company'), ('obj6', 'http://www.wikidata.org/entity/Q1200552'), ('cName1', 'Marvel Entertainment')]
# [('obj5', 'http://www.wikidata.org/entity/Q7414'), ('cName', 'The Walt Disney Company'), ('obj6', 'http://www.wikidata.org/entity/Q138709'), ('cName1', 'Nat Geo Wild')]
# [('obj5', 'http://www.wikidata.org/entity/Q7414'), ('cName', 'The Walt Disney Company'), ('obj6', 'http://www.wikidata.org/entity/Q157118'), ('cName1', 'National Geographic Channel')]
# [('obj5', 'http://www.wikidata.org/entity/Q7414'), ('cName', 'The Walt Disney Company'), ('obj6', 'http://www.wikidata.org/entity/Q3336288'), ('cName1', 'Nat Geo Wild')]
# [('obj5', 'http://www.wikidata.org/entity/Q7414'), ('cName', 'The Walt Disney Company'), ('obj6', 'http://www.wikidata.org/entity/Q1047410'), ('cName1', 'Walt Disney Animation Studios')]
# [('obj5', 'http://www.wikidata.org/entity/Q7414'), ('cName', 'The Walt Disney Company'), ('obj6', 'http://www.wikidata.org/entity/Q634019'), ('cName1', '20th Century Animation')]
# [('obj5', 'http://www.wikidata.org/entity/Q7414'), ('cName', 'The Walt Disney Company'), ('obj6', 'http://www.wikidata.org/entity/Q1319610'), ('cName1', 'Lifetime')]
# [('obj5', 'http://www.wikidata.org/entity/Q7414'), ('cName', 'The Walt Disney Company'), ('obj6', 'http://www.wikidata.org/entity/Q18148065'), ('cName1', 'Frozen')]
# [('obj5', 'http://www.wikidata.org/entity/Q7414'), ('cName', 'The Walt Disney Company'), ('obj6', 'http://www.wikidata.org/entity/Q2081339'), ('cName1', 'Disneytoon Studios')]
# [('obj5', 'http://www.wikidata.org/entity/Q7414'), ('cName', 'The Walt Disney Company'), ('obj6', 'http://www.wikidata.org/entity/Q2216535'), ('cName1', 'Walt Disney Studios')]
# [('obj5', 'http://www.wikidata.org/entity/Q7414'), ('cName', 'The Walt Disney Company'), ('obj6', 'http://www.wikidata.org/entity/Q1348264'), ('cName1', 'Hollywood Pictures')]
# [('obj5', 'http://www.wikidata.org/entity/Q7414'), ('cName', 'The Walt Disney Company'), ('obj6', 'http://www.wikidata.org/entity/Q242446'), ('cName1', 'Lucasfilm')]
# [('obj5', 'http://www.wikidata.org/entity/Q7414'), ('cName', 'The Walt Disney Company'), ('obj6', 'http://www.wikidata.org/entity/Q277561'), ('cName1', 'A&E')]
# [('obj5', 'http://www.wikidata.org/entity/Q7414'), ('cName', 'The Walt Disney Company'), ('obj6', 'http://www.wikidata.org/entity/Q83723'), ('cName1', 'A&E Networks')]
# [('obj5', 'http://www.wikidata.org/entity/Q7414'), ('cName', 'The Walt Disney Company'), ('obj6', 'http://www.wikidata.org/entity/Q2378052'), ('cName1', 'Disney Channel Spain')]
# [('obj5', 'http://www.wikidata.org/entity/Q7414'), ('cName', 'The Walt Disney Company'), ('obj6', 'http://www.wikidata.org/entity/Q313621'), ('cName1', 'Disney Junior')]
# [('obj5', 'http://www.wikidata.org/entity/Q7414'), ('cName', 'The Walt Disney Company'), ('obj6', 'http://www.wikidata.org/entity/Q654073'), ('cName1', 'Walt Disney Television')]
# [('obj5', 'http://www.wikidata.org/entity/Q7414'), ('cName', 'The Walt Disney Company'), ('obj6', 'http://www.wikidata.org/entity/Q5930877'), ('cName1', 'Jetix (Spain)')]
# [('obj5', 'http://www.wikidata.org/entity/Q7414'), ('cName', 'The Walt Disney Company'), ('obj6', 'http://www.wikidata.org/entity/Q6145466'), ('cName1', 'The Walt Disney Company Iberia')]
# [('obj5', 'http://www.wikidata.org/entity/Q7414'), ('cName', 'The Walt Disney Company'), ('obj6', 'http://www.wikidata.org/entity/Q2501552'), ('cName1', 'Disneynature')]
# [('obj5', 'http://www.wikidata.org/entity/Q7414'), ('cName', 'The Walt Disney Company'), ('obj6', 'http://www.wikidata.org/entity/Q14928314'), ('cName1', 'The Walt Disney Company Latin America')]
# [('obj5', 'http://www.wikidata.org/entity/Q7414'), ('cName', 'The Walt Disney Company'), ('obj6', 'http://www.wikidata.org/entity/Q3299645'), ('cName1', 'Disney Junior')]
# [('obj5', 'http://www.wikidata.org/entity/Q7414'), ('cName', 'The Walt Disney Company'), ('obj6', 'http://www.wikidata.org/entity/Q15070400'), ('cName1', "Mind's Eye Productions")]
# [('obj5', 'http://www.wikidata.org/entity/Q7414'), ('cName', 'The Walt Disney Company'), ('obj6', 'http://www.wikidata.org/entity/Q3497261'), ('cName1', 'Starwave')]
# [('obj5', 'http://www.wikidata.org/entity/Q7414'), ('cName', 'The Walt Disney Company'), ('obj6', 'http://www.wikidata.org/entity/Q3628946'), ('cName1', 'Star Sports')]
# [('obj5', 'http://www.wikidata.org/entity/Q7414'), ('cName', 'The Walt Disney Company'), ('obj6', 'http://www.wikidata.org/entity/Q11681754'), ('cName1', 'FXX')]
# [('obj5', 'http://www.wikidata.org/entity/Q7414'), ('cName', 'The Walt Disney Company'), ('obj6', 'http://www.wikidata.org/entity/Q6739276'), ('cName1', 'Disney Digital Network')]
# [('obj5', 'http://www.wikidata.org/entity/Q7414'), ('cName', 'The Walt Disney Company'), ('obj6', 'http://www.wikidata.org/entity/Q738088'), ('cName1', '24Kitchen')]
# [('obj5', 'http://www.wikidata.org/entity/Q7414'), ('cName', 'The Walt Disney Company'), ('obj6', 'http://www.wikidata.org/entity/Q264058'), ('cName1', 'H2')]
# [('obj5', 'http://www.wikidata.org/entity/Q7414'), ('cName', 'The Walt Disney Company'), ('obj6', 'http://www.wikidata.org/entity/Q29015971'), ('cName1', 'Disney Streaming Services')]
# [('obj5', 'http://www.wikidata.org/entity/Q7414'), ('cName', 'The Walt Disney Company'), ('obj6', 'http://www.wikidata.org/entity/Q54857'), ('cName1', 'Radio Disney')]
# [('obj5', 'http://www.wikidata.org/entity/Q7414'), ('cName', 'The Walt Disney Company'), ('obj6', 'http://www.wikidata.org/entity/Q313173'), ('cName1', 'Toon Disney')]
# [('obj5', 'http://www.wikidata.org/entity/Q7414'), ('cName', 'The Walt Disney Company'), ('obj6', 'http://www.wikidata.org/entity/Q206859'), ('cName1', 'Walt Disney World Resort')]
# [('obj5', 'http://www.wikidata.org/entity/Q7414'), ('cName', 'The Walt Disney Company'), ('obj6', 'http://www.wikidata.org/entity/Q684994'), ('cName1', 'Super RTL')]
# [('obj5', 'http://www.wikidata.org/entity/Q7414'), ('cName', 'The Walt Disney Company'), ('obj6', 'http://www.wikidata.org/entity/Q2125296'), ('cName1', 'Disney Springs')]
# [('obj5', 'http://www.wikidata.org/entity/Q7414'), ('cName', 'The Walt Disney Company'), ('obj6', 'http://www.wikidata.org/entity/Q217776'), ('cName1', 'ESPN')]
# [('obj5', 'http://www.wikidata.org/entity/Q7414'), ('cName', 'The Walt Disney Company'), ('obj6', 'http://www.wikidata.org/entity/Q3030368'), ('cName1', 'Disney Channel')]
# ...
# [('obj5', 'http://www.wikidata.org/entity/Q7414'), ('cName', 'The Walt Disney Company'), ('obj6', 'http://www.wikidata.org/entity/Q4837590'), ('cName1', 'babble.com')]
# [('obj5', 'http://www.wikidata.org/entity/Q7414'), ('cName', 'The Walt Disney Company'), ('obj6', 'http://www.wikidata.org/entity/Q9004339'), ('cName1', 'History en Español')]
# [('obj5', 'http://www.wikidata.org/entity/Q7414'), ('cName', 'The Walt Disney Company'), ('obj6', 'http://www.wikidata.org/entity/Q849284'), ('cName1', 'El Capitan Theatre')]
# [('obj5', 'http://www.wikidata.org/entity/Q7414'), ('cName', 'The Walt Disney Company'), ('obj6', 'http://www.wikidata.org/entity/Q16679850'), ('cName1', 'The Walt Disney Company Germany')]
# [('obj5', 'http://www.wikidata.org/entity/Q7414'), ('cName', 'The Walt Disney Company'), ('obj6', 'http://www.wikidata.org/entity/Q17625387'), ('cName1', 'Playhouse Disney (Spain)')]
# [('obj5', 'http://www.wikidata.org/entity/Q7414'), ('cName', 'The Walt Disney Company'), ('obj6', 'http://www.wikidata.org/entity/Q3433822'), ('cName1', 'Crime & Investigation Network')]
# [('obj5', 'http://www.wikidata.org/entity/Q7414'), ('cName', 'The Walt Disney Company'), ('obj6', 'http://www.wikidata.org/entity/Q3150870'), ('cName1', 'Infoseek')]
# [('obj5', 'http://www.wikidata.org/entity/Q7414'), ('cName', 'The Walt Disney Company'), ('obj6', 'http://www.wikidata.org/entity/Q16558744'), ('cName1', 'ESPN 2 (Brasil)')]
# [('obj5', 'http://www.wikidata.org/entity/Q7414'), ('cName', 'The Walt Disney Company'), ('obj6', 'http://www.wikidata.org/entity/Q5816263'), ('cName1', 'ESPN 2 (Andino)')]
# [('obj5', 'http://www.wikidata.org/entity/Q7414'), ('cName', 'The Walt Disney Company'), ('obj6', 'http://www.wikidata.org/entity/Q5816271'), ('cName1', 'ESPN 3 (Latinoamérica)')]
# [('obj5', 'http://www.wikidata.org/entity/Q7414'), ('cName', 'The Walt Disney Company'), ('obj6', 'http://www.wikidata.org/entity/Q6167975'), ('cName1', "Jayski's Silly Season Site")]
# [('obj5', 'http://www.wikidata.org/entity/Q7414'), ('cName', 'The Walt Disney Company'), ('obj6', 'http://www.wikidata.org/entity/Q8771352'), ('cName1', 'ESPN+ (Latin America)')]
# [('obj5', 'http://www.wikidata.org/entity/Q7414'), ('cName', 'The Walt Disney Company'), ('obj6', 'http://www.wikidata.org/entity/Q334671'), ('cName1', 'Disney Channel Scandinavia')]
# [('obj5', 'http://www.wikidata.org/entity/Q7414'), ('cName', 'The Walt Disney Company'), ('obj6', 'http://www.wikidata.org/entity/Q3565620'), ('cName1', 'Walt Disney Publications')]
# [('obj5', 'http://www.wikidata.org/entity/Q7414'), ('cName', 'The Walt Disney Company'), ('obj6', 'http://www.wikidata.org/entity/Q38072167'), ('cName1', 'FX Movies (Latin America)')]
# [('obj5', 'http://www.wikidata.org/entity/Q7414'), ('cName', 'The Walt Disney Company'), ('obj6', 'http://www.wikidata.org/entity/Q5270612'), ('cName1', 'Fox Life India')]
# [('obj5', 'http://www.wikidata.org/entity/Q7414'), ('cName', 'The Walt Disney Company'), ('obj6', 'http://www.wikidata.org/entity/Q637164'), ('cName1', 'The Baby Einstein Company')]
# [('obj5', 'http://www.wikidata.org/entity/Q7414'), ('cName', 'The Walt Disney Company'), ('obj6', 'http://www.wikidata.org/entity/Q3039254'), ('cName1', 'Dream Quest Images')]
# [('obj5', 'http://www.wikidata.org/entity/Q7414'), ('cName', 'The Walt Disney Company'), ('obj6', 'http://www.wikidata.org/entity/Q5185160'), ('cName1', 'Crime & Investigation Network')]
# [('obj5', 'http://www.wikidata.org/entity/Q7414'), ('cName', 'The Walt Disney Company'), ('obj6', 'http://www.wikidata.org/entity/Q5185161'), ('cName1', 'Crime & Investigation Network Asia')]
# [('obj5', 'http://www.wikidata.org/entity/Q7414'), ('cName', 'The Walt Disney Company'), ('obj6', 'http://www.wikidata.org/entity/Q3064766'), ('cName1', 'Fall Line Studios')]
# [('obj5', 'http://www.wikidata.org/entity/Q7414'), ('cName', 'The Walt Disney Company'), ('obj6', 'http://www.wikidata.org/entity/Q3523271'), ('cName1', 'The Walt Disney Company CIS')]
# [('obj5', 'http://www.wikidata.org/entity/Q7414'), ('cName', 'The Walt Disney Company'), ('obj6', 'http://www.wikidata.org/entity/Q3523272'), ('cName1', 'The Walt Disney Company Southeast Asia')]
# [('obj5', 'http://www.wikidata.org/entity/Q7414'), ('cName', 'The Walt Disney Company'), ('obj6', 'http://www.wikidata.org/entity/Q9693853'), ('cName1', 'History (European TV channel)')]
# [('obj5', 'http://www.wikidata.org/entity/Q7414'), ('cName', 'The Walt Disney Company'), ('obj6', 'http://www.wikidata.org/entity/Q6148912'), ('cName1', 'Toon Disney Spain')]
# [('obj5', 'http://www.wikidata.org/entity/Q7414'), ('cName', 'The Walt Disney Company'), ('obj6', 'http://www.wikidata.org/entity/Q2915959'), ('cName1', "Disney's River Country")]
# [('obj5', 'http://www.wikidata.org/entity/Q7414'), ('cName', 'The Walt Disney Company'), ('obj6', 'http://www.wikidata.org/entity/Q1228987'), ('cName1', 'Disney Digital 3-D')]
# [('obj5', 'http://www.wikidata.org/entity/Q7414'), ('cName', 'The Walt Disney Company'), ('obj6', 'http://www.wikidata.org/entity/Q16835471'), ('cName1', 'Disney Junior Greece')]
# [('obj5', 'http://www.wikidata.org/entity/Q7414'), ('cName', 'The Walt Disney Company'), ('obj6', 'http://www.wikidata.org/entity/Q16991842'), ('cName1', 'Disney Junior Poland')]
# [('obj5', 'http://www.wikidata.org/entity/Q7414'), ('cName', 'The Walt Disney Company'), ('obj6', 'http://www.wikidata.org/entity/Q17014745'), ('cName1', 'BabyZone.com')]
# [('obj5', 'http://www.wikidata.org/entity/Q7414'), ('cName', 'The Walt Disney Company'), ('obj6', 'http://www.wikidata.org/entity/Q17082860'), ('cName1', 'spoonful.com')]
# [('obj5', 'http://www.wikidata.org/entity/Q7414'), ('cName', 'The Walt Disney Company'), ('obj6', 'http://www.wikidata.org/entity/Q17145072'), ('cName1', 'STAR World Premiere')]
# [('obj5', 'http://www.wikidata.org/entity/Q7414'), ('cName', 'The Walt Disney Company'), ('obj6', 'http://www.wikidata.org/entity/Q17183023'), ('cName1', 'Radio Disney Group, LLC')]
# [('obj5', 'http://www.wikidata.org/entity/Q7414'), ('cName', 'The Walt Disney Company'), ('obj6', 'http://www.wikidata.org/entity/Q17639984'), ('cName1', 'The Walt Disney Company Limited')]
# [('obj5', 'http://www.wikidata.org/entity/Q7414'), ('cName', 'The Walt Disney Company'), ('obj6', 'http://www.wikidata.org/entity/Q18149304'), ('cName1', 'Disney Tsum Tsum')]
# [('obj5', 'http://www.wikidata.org/entity/Q7414'), ('cName', 'The Walt Disney Company'), ('obj6', 'http://www.wikidata.org/entity/Q18207757'), ('cName1', 'STAR Sports 2')]
# [('obj5', 'http://www.wikidata.org/entity/Q7414'), ('cName', 'The Walt Disney Company'), ('obj6', 'http://www.wikidata.org/entity/Q19868095'), ('cName1', 'Disney XD')]
# [('obj5', 'http://www.wikidata.org/entity/Q7414'), ('cName', 'The Walt Disney Company'), ('obj6', 'http://www.wikidata.org/entity/Q23022746'), ('cName1', 'Star Utsav Movies')]
# [('obj5', 'http://www.wikidata.org/entity/Q7414'), ('cName', 'The Walt Disney Company'), ('obj6', 'http://www.wikidata.org/entity/Q25377492'), ('cName1', 'The Walt Disney Company Australia')]
# [('obj5', 'http://www.wikidata.org/entity/Q7414'), ('cName', 'The Walt Disney Company'), ('obj6', 'http://www.wikidata.org/entity/Q25384903'), ('cName1', 'The Walt Disney Company China')]
# [('obj5', 'http://www.wikidata.org/entity/Q7414'), ('cName', 'The Walt Disney Company'), ('obj6', 'http://www.wikidata.org/entity/Q28457298'), ('cName1', 'FoxNext')]
# [('obj5', 'http://www.wikidata.org/entity/Q7414'), ('cName', 'The Walt Disney Company'), ('obj6', 'http://www.wikidata.org/entity/Q2994210'), ('cName1', 'STAR Sports 3')]
# [('obj5', 'http://www.wikidata.org/entity/Q7414'), ('cName', 'The Walt Disney Company'), ('obj6', 'http://www.wikidata.org/entity/Q3030351'), ('cName1', 'Disney-ABC Cable Network Group')]
# [('obj5', 'http://www.wikidata.org/entity/Q7414'), ('cName', 'The Walt Disney Company'), ('obj6', 'http://www.wikidata.org/entity/Q3030429'), ('cName1', 'Disney Institute')]
# [('obj5', 'http://www.wikidata.org/entity/Q7414'), ('cName', 'The Walt Disney Company'), ('obj6', 'http://www.wikidata.org/entity/Q3030447'), ('cName1', 'Disney Media Networks')]
# [('obj5', 'http://www.wikidata.org/entity/Q7414'), ('cName', 'The Walt Disney Company'), ('obj6', 'http://www.wikidata.org/entity/Q3030511'), ('cName1', 'Disneyland Railroad')]
# [('obj5', 'http://www.wikidata.org/entity/Q7414'), ('cName', 'The Walt Disney Company'), ('obj6', 'http://www.wikidata.org/entity/Q3046171'), ('cName1', 'ESPN Zone')]
# [('obj5', 'http://www.wikidata.org/entity/Q7414'), ('cName', 'The Walt Disney Company'), ('obj6', 'http://www.wikidata.org/entity/Q3094998'), ('cName1', 'Gamestar')]
# [('obj5', 'http://www.wikidata.org/entity/Q7414'), ('cName', 'The Walt Disney Company'), ('obj6', 'http://www.wikidata.org/entity/Q3146319'), ('cName1', 'Hotels of The Walt Disney Company')]
# [('obj5', 'http://www.wikidata.org/entity/Q7414'), ('cName', 'The Walt Disney Company'), ('obj6', 'http://www.wikidata.org/entity/Q3150108'), ('cName1', 'Indiana Jones Adventure')]
# [('obj5', 'http://www.wikidata.org/entity/Q7414'), ('cName', 'The Walt Disney Company'), ('obj6', 'http://www.wikidata.org/entity/Q3177799'), ('cName1', 'Jetix Europe')]
# [('obj5', 'http://www.wikidata.org/entity/Q7414'), ('cName', 'The Walt Disney Company'), ('obj6', 'http://www.wikidata.org/entity/Q3191359'), ('cName1', 'KESN')]
# [('obj5', 'http://www.wikidata.org/entity/Q7414'), ('cName', 'The Walt Disney Company'), ('obj6', 'http://www.wikidata.org/entity/Q3366991'), ('cName1', 'Partners Federal Credit Union')]
# [('obj5', 'http://www.wikidata.org/entity/Q7414'), ('cName', 'The Walt Disney Company'), ('obj6', 'http://www.wikidata.org/entity/Q3561108'), ('cName1', 'Vista Federal Credit Union')]
# [('obj5', 'http://www.wikidata.org/entity/Q7414'), ('cName', 'The Walt Disney Company'), ('obj6', 'http://www.wikidata.org/entity/Q3564732'), ('cName1', 'WMVP')]
# [('obj5', 'http://www.wikidata.org/entity/Q7414'), ('cName', 'The Walt Disney Company'), ('obj6', 'http://www.wikidata.org/entity/Q3565607'), ('cName1', 'Disney Educational Productions')]
# [('obj5', 'http://www.wikidata.org/entity/Q7414'), ('cName', 'The Walt Disney Company'), ('obj6', 'http://www.wikidata.org/entity/Q3565612'), ('cName1', 'Walt Disney International')]
# [('obj5', 'http://www.wikidata.org/entity/Q7414'), ('cName', 'The Walt Disney Company'), ('obj6', 'http://www.wikidata.org/entity/Q3630152'), ('cName1', 'STAR Utsav')]
# [('obj5', 'http://www.wikidata.org/entity/Q7414'), ('cName', 'The Walt Disney Company'), ('obj6', 'http://www.wikidata.org/entity/Q3631491'), ('cName1', 'STAR Gold')]
# [('obj5', 'http://www.wikidata.org/entity/Q7414'), ('cName', 'The Walt Disney Company'), ('obj6', 'http://www.wikidata.org/entity/Q4132097'), ('cName1', 'Military History')]
# [('obj5', 'http://www.wikidata.org/entity/Q7414'), ('cName', 'The Walt Disney Company'), ('obj6', 'http://www.wikidata.org/entity/Q45001184'), ('cName1', 'National Geographic Kids Abu Dhabi')]
# [('obj5', 'http://www.wikidata.org/entity/Q7414'), ('cName', 'The Walt Disney Company'), ('obj6', 'http://www.wikidata.org/entity/Q49402184'), ('cName1', 'Fox Movies')]
# [('obj5', 'http://www.wikidata.org/entity/Q7414'), ('cName', 'The Walt Disney Company'), ('obj6', 'http://www.wikidata.org/entity/Q5282418'), ('cName1', 'Disney Channel')]
# [('obj5', 'http://www.wikidata.org/entity/Q7414'), ('cName', 'The Walt Disney Company'), ('obj6', 'http://www.wikidata.org/entity/Q5282427'), ('cName1', 'Disney Channel Malaysia')]
# [('obj5', 'http://www.wikidata.org/entity/Q7414'), ('cName', 'The Walt Disney Company'), ('obj6', 'http://www.wikidata.org/entity/Q5282458'), ('cName1', 'Disney Junior')]
# [('obj5', 'http://www.wikidata.org/entity/Q7414'), ('cName', 'The Walt Disney Company'), ('obj6', 'http://www.wikidata.org/entity/Q5476702'), ('cName1', 'Fox Filipino')]
# [('obj5', 'http://www.wikidata.org/entity/Q7414'), ('cName', 'The Walt Disney Company'), ('obj6', 'http://www.wikidata.org/entity/Q5476820'), ('cName1', 'Fox Movie Channel')]
# [('obj5', 'http://www.wikidata.org/entity/Q7414'), ('cName', 'The Walt Disney Company'), ('obj6', 'http://www.wikidata.org/entity/Q7280765'), ('cName1', 'Radio Disney Brasil')]
# [('obj5', 'http://www.wikidata.org/entity/Q7414'), ('cName', 'The Walt Disney Company'), ('obj6', 'http://www.wikidata.org/entity/Q7394683'), ('cName1', 'STAR World India')]
# [('obj5', 'http://www.wikidata.org/entity/Q7426051'), ('cName', 'Satellite News Channel')]
# [('obj5', 'http://www.wikidata.org/entity/Q746676'), ('cName', 'Industrial Light & Magic')]
# [('obj5', 'http://www.wikidata.org/entity/Q7747662'), ('cName', "Disney's The Little Mermaid")]
# [('obj5', 'http://www.wikidata.org/entity/Q7949486'), ('cName', 'WFRO')]
# [('obj5', 'http://www.wikidata.org/entity/Q83723'), ('cName', 'A&E Networks'), ('obj6', 'http://www.wikidata.org/entity/Q622329'), ('cName1', 'The Biography Channel')]
# [('obj5', 'http://www.wikidata.org/entity/Q83723'), ('cName', 'A&E Networks'), ('obj6', 'http://www.wikidata.org/entity/Q277561'), ('cName1', 'A&E')]
# [('obj5', 'http://www.wikidata.org/entity/Q83723'), ('cName', 'A&E Networks'), ('obj6', 'http://www.wikidata.org/entity/Q264058'), ('cName1', 'H2')]
# [('obj5', 'http://www.wikidata.org/entity/Q83723'), ('cName', 'A&E Networks'), ('obj6', 'http://www.wikidata.org/entity/Q6310201'), ('cName1', 'History TV18')]
# [('obj5', 'http://www.wikidata.org/entity/Q83723'), ('cName', 'A&E Networks'), ('obj6', 'http://www.wikidata.org/entity/Q6545534'), ('cName1', 'LMN')]
# [('obj5', 'http://www.wikidata.org/entity/Q83723'), ('cName', 'A&E Networks'), ('obj6', 'http://www.wikidata.org/entity/Q23022864'), ('cName1', 'Viceland')]
# [('obj5', 'http://www.wikidata.org/entity/Q83723'), ('cName', 'A&E Networks'), ('obj6', 'http://www.wikidata.org/entity/Q30566378'), ('cName1', 'A&E')]
# [('obj5', 'http://www.wikidata.org/entity/Q83723'), ('cName', 'A&E Networks'), ('obj6', 'http://www.wikidata.org/entity/Q30919172'), ('cName1', 'History (Latinoamérica)')]
# [('obj5', 'http://www.wikidata.org/entity/Q83723'), ('cName', 'A&E Networks'), ('obj6', 'http://www.wikidata.org/entity/Q17619901'), ('cName1', 'Lifetime Latinoamérica')]
# [('obj5', 'http://www.wikidata.org/entity/Q83723'), ('cName', 'A&E Networks'), ('obj6', 'http://www.wikidata.org/entity/Q3238409'), ('cName1', 'Lifetime Entertainment Services')]
# [('obj5', 'http://www.wikidata.org/entity/Q83723'), ('cName', 'A&E Networks'), ('obj6', 'http://www.wikidata.org/entity/Q3433822'), ('cName1', 'Crime & Investigation Network')]
# [('obj5', 'http://www.wikidata.org/entity/Q83723'), ('cName', 'A&E Networks'), ('obj6', 'http://www.wikidata.org/entity/Q5185160'), ('cName1', 'Crime & Investigation Network')]
# [('obj5', 'http://www.wikidata.org/entity/Q83723'), ('cName', 'A&E Networks'), ('obj6', 'http://www.wikidata.org/entity/Q5185161'), ('cName1', 'Crime & Investigation Network Asia')]
# [('obj5', 'http://www.wikidata.org/entity/Q83723'), ('cName', 'A&E Networks'), ('obj6', 'http://www.wikidata.org/entity/Q9693853'), ('cName1', 'History (European TV channel)')]
# [('obj5', 'http://www.wikidata.org/entity/Q849284'), ('cName', 'El Capitan Theatre')]
# [('obj5', 'http://www.wikidata.org/entity/Q8771352'), ('cName', 'ESPN+ (Latin America)')]
# [('obj5', 'http://www.wikidata.org/entity/Q885885'), ('cName', 'Blue Sky Studios')]
# [('obj5', 'http://www.wikidata.org/entity/Q9004339'), ('cName', 'History en Español')]
# [('obj5', 'http://www.wikidata.org/entity/Q902959'), ('cName', 'Times Square Studios')]
# [('obj5', 'http://www.wikidata.org/entity/Q908662'), ('cName', 'Dimension Films')]
# [('obj5', 'http://www.wikidata.org/entity/Q919514'), ('cName', 'Fox Studios Australia')]
# [('obj5', 'http://www.wikidata.org/entity/Q953040'), ('cName', 'Searchlight Pictures')]
# [('obj5', 'http://www.wikidata.org/entity/Q9693853'), ('cName', 'History (European TV channel)')]
# [('obj5', 'http://www.wikidata.org/entity/Q969695'), ('cName', 'Mickey Mouse')]
# [('obj5', 'http://www.wikidata.org/entity/Q973987'), ('cName', 'Shanghai Disney Resort')]
# 598

# %% [markdown]
# Changing the operators: from * to +. I will retrieve all controlled companies of Disney.

# %%
queryString = """
SELECT DISTINCT ?obj5 ?cName ?obj6 ?cName1
WHERE {

wd:Q7414 wdt:P31 wd:Q4830453  . 
wd:Q7414 wdt:P1830+ ?obj5 . #owner of

# ?obj5 <http://schema.org/name> ?cName .

OPTIONAL{
# ?obj5 wdt:P1830+ ?obj6 .
# ?obj6 <http://schema.org/name> ?cName1 .
}

} 
ORDER BY ASC(?obj5)
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('obj5', 'http://www.wikidata.org/entity/Q10279075'), ('cName', 'Fox Movies')]
# [('obj5', 'http://www.wikidata.org/entity/Q1047009'), ('cName', 'Disney Store')]
# [('obj5', 'http://www.wikidata.org/entity/Q1047410'), ('cName', 'Walt Disney Animation Studios')]
# [('obj5', 'http://www.wikidata.org/entity/Q1052042'), ('cName', 'Epcot')]
# [('obj5', 'http://www.wikidata.org/entity/Q1118859'), ('cName', 'Fox Crime')]
# [('obj5', 'http://www.wikidata.org/entity/Q1141129'), ('cName', 'CrossGen')]
# [('obj5', 'http://www.wikidata.org/entity/Q11681754'), ('cName', 'FXX')]
# [('obj5', 'http://www.wikidata.org/entity/Q1169075'), ('cName', 'Lucasfilm Animation')]
# [('obj5', 'http://www.wikidata.org/entity/Q1189112'), ('cName', 'Nat Geo Music')]
# [('obj5', 'http://www.wikidata.org/entity/Q1200552'), ('cName', 'Marvel Entertainment')]
# [('obj5', 'http://www.wikidata.org/entity/Q1204077'), ('cName', 'ImageMovers')]
# [('obj5', 'http://www.wikidata.org/entity/Q1228987'), ('cName', 'Disney Digital 3-D')]
# [('obj5', 'http://www.wikidata.org/entity/Q1228989'), ('cName', 'Disney Dream')]
# [('obj5', 'http://www.wikidata.org/entity/Q1228992'), ('cName', 'Disney Fantasy')]
# [('obj5', 'http://www.wikidata.org/entity/Q1229035'), ('cName', 'Disney Interactive Studios')]
# [('obj5', 'http://www.wikidata.org/entity/Q1233073'), ('cName', 'Walt Disney Motion Pictures Group')]
# [('obj5', 'http://www.wikidata.org/entity/Q127552'), ('cName', 'Pixar')]
# [('obj5', 'http://www.wikidata.org/entity/Q130809'), ('cName', 'Star TV'), ('obj6', 'http://www.wikidata.org/entity/Q3046173'), ('cName1', 'ESPN Star Sports')]
# [('obj5', 'http://www.wikidata.org/entity/Q130809'), ('cName', 'Star TV'), ('obj6', 'http://www.wikidata.org/entity/Q306585'), ('cName1', 'Channel V')]
# [('obj5', 'http://www.wikidata.org/entity/Q130809'), ('cName', 'Star TV'), ('obj6', 'http://www.wikidata.org/entity/Q5072463'), ('cName1', 'Channel [V] Philippines')]
# [('obj5', 'http://www.wikidata.org/entity/Q1319610'), ('cName', 'Lifetime')]
# [('obj5', 'http://www.wikidata.org/entity/Q1348264'), ('cName', 'Hollywood Pictures')]
# [('obj5', 'http://www.wikidata.org/entity/Q138709'), ('cName', 'Nat Geo Wild')]
# [('obj5', 'http://www.wikidata.org/entity/Q1431781'), ('cName', 'Disney Parks, Experiences and Products'), ('obj6', 'http://www.wikidata.org/entity/Q1052042'), ('cName1', 'Epcot')]
# [('obj5', 'http://www.wikidata.org/entity/Q14928314'), ('cName', 'The Walt Disney Company Latin America')]
# [('obj5', 'http://www.wikidata.org/entity/Q15070400'), ('cName', "Mind's Eye Productions")]
# [('obj5', 'http://www.wikidata.org/entity/Q157118'), ('cName', 'National Geographic Channel'), ('obj6', 'http://www.wikidata.org/entity/Q138709'), ('cName1', 'Nat Geo Wild')]
# [('obj5', 'http://www.wikidata.org/entity/Q157118'), ('cName', 'National Geographic Channel'), ('obj6', 'http://www.wikidata.org/entity/Q3336288'), ('cName1', 'Nat Geo Wild')]
# [('obj5', 'http://www.wikidata.org/entity/Q157118'), ('cName', 'National Geographic Channel'), ('obj6', 'http://www.wikidata.org/entity/Q2299634'), ('cName1', 'National Geographic People')]
# [('obj5', 'http://www.wikidata.org/entity/Q15731902'), ('cName', 'Aladdin')]
# [('obj5', 'http://www.wikidata.org/entity/Q16155122'), ('cName', 'Beauty and the Beast')]
# [('obj5', 'http://www.wikidata.org/entity/Q1621107'), ('cName', 'History')]
# [('obj5', 'http://www.wikidata.org/entity/Q16271976'), ('cName', 'Movies OK')]
# [('obj5', 'http://www.wikidata.org/entity/Q16558744'), ('cName', 'ESPN 2 (Brasil)')]
# [('obj5', 'http://www.wikidata.org/entity/Q16679850'), ('cName', 'The Walt Disney Company Germany')]
# [('obj5', 'http://www.wikidata.org/entity/Q16683129'), ('cName', 'Walt Disney Internet Group')]
# [('obj5', 'http://www.wikidata.org/entity/Q16835471'), ('cName', 'Disney Junior Greece')]
# [('obj5', 'http://www.wikidata.org/entity/Q16911414'), ('cName', 'Grantland')]
# [('obj5', 'http://www.wikidata.org/entity/Q169889'), ('cName', 'American Broadcasting Company'), ('obj6', 'http://www.wikidata.org/entity/Q17085515'), ('cName1', 'ESPN Inc.')]
# [('obj5', 'http://www.wikidata.org/entity/Q169889'), ('cName', 'American Broadcasting Company'), ('obj6', 'http://www.wikidata.org/entity/Q287171'), ('cName1', 'ABC News')]
# [('obj5', 'http://www.wikidata.org/entity/Q169889'), ('cName', 'American Broadcasting Company'), ('obj6', 'http://www.wikidata.org/entity/Q51595207'), ('cName1', 'list of production companies owned by the American Broadcasting Company')]
# [('obj5', 'http://www.wikidata.org/entity/Q169889'), ('cName', 'American Broadcasting Company'), ('obj6', 'http://www.wikidata.org/entity/Q7426051'), ('cName1', 'Satellite News Channel')]
# [('obj5', 'http://www.wikidata.org/entity/Q169889'), ('cName', 'American Broadcasting Company'), ('obj6', 'http://www.wikidata.org/entity/Q7949486'), ('cName1', 'WFRO')]
# [('obj5', 'http://www.wikidata.org/entity/Q169889'), ('cName', 'American Broadcasting Company'), ('obj6', 'http://www.wikidata.org/entity/Q600669'), ('cName1', 'FiveThirtyEight')]
# [('obj5', 'http://www.wikidata.org/entity/Q16991842'), ('cName', 'Disney Junior Poland')]
# [('obj5', 'http://www.wikidata.org/entity/Q17014745'), ('cName', 'BabyZone.com')]
# [('obj5', 'http://www.wikidata.org/entity/Q17018738'), ('cName', 'Kingsman')]
# [('obj5', 'http://www.wikidata.org/entity/Q17070395'), ('cName', 'MyMagic+')]
# [('obj5', 'http://www.wikidata.org/entity/Q17082860'), ('cName', 'spoonful.com')]
# [('obj5', 'http://www.wikidata.org/entity/Q17085515'), ('cName', 'ESPN Inc.')]
# [('obj5', 'http://www.wikidata.org/entity/Q17145072'), ('cName', 'STAR World Premiere')]
# [('obj5', 'http://www.wikidata.org/entity/Q17183023'), ('cName', 'Radio Disney Group, LLC')]
# [('obj5', 'http://www.wikidata.org/entity/Q17511049'), ('cName', 'Alice in Wonderland')]
# [('obj5', 'http://www.wikidata.org/entity/Q17619901'), ('cName', 'Lifetime Latinoamérica')]
# [('obj5', 'http://www.wikidata.org/entity/Q17625387'), ('cName', 'Playhouse Disney (Spain)')]
# [('obj5', 'http://www.wikidata.org/entity/Q17639984'), ('cName', 'The Walt Disney Company Limited')]
# [('obj5', 'http://www.wikidata.org/entity/Q178837'), ('cName', 'Disney Channel')]
# [('obj5', 'http://www.wikidata.org/entity/Q17984894'), ('cName', 'Winnie the Pooh')]
# [('obj5', 'http://www.wikidata.org/entity/Q181185'), ('cName', 'Disneyland')]
# [('obj5', 'http://www.wikidata.org/entity/Q18148065'), ('cName', 'Frozen')]
# [('obj5', 'http://www.wikidata.org/entity/Q18149304'), ('cName', 'Disney Tsum Tsum')]
# [('obj5', 'http://www.wikidata.org/entity/Q18207757'), ('cName', 'STAR Sports 2')]
# [('obj5', 'http://www.wikidata.org/entity/Q1858139'), ('cName', 'Disney XD')]
# [('obj5', 'http://www.wikidata.org/entity/Q18636714'), ('cName', 'Disney utilidor system')]
# [('obj5', 'http://www.wikidata.org/entity/Q191224'), ('cName', 'Walt Disney Pictures'), ('obj6', 'http://www.wikidata.org/entity/Q15731902'), ('cName1', 'Aladdin')]
# [('obj5', 'http://www.wikidata.org/entity/Q191224'), ('cName', 'Walt Disney Pictures'), ('obj6', 'http://www.wikidata.org/entity/Q1047410'), ('cName1', 'Walt Disney Animation Studios')]
# [('obj5', 'http://www.wikidata.org/entity/Q191224'), ('cName', 'Walt Disney Pictures'), ('obj6', 'http://www.wikidata.org/entity/Q2081339'), ('cName1', 'Disneytoon Studios')]
# [('obj5', 'http://www.wikidata.org/entity/Q191224'), ('cName', 'Walt Disney Pictures'), ('obj6', 'http://www.wikidata.org/entity/Q2944088'), ('cName1', 'Pixar Canada')]
# [('obj5', 'http://www.wikidata.org/entity/Q191224'), ('cName', 'Walt Disney Pictures'), ('obj6', 'http://www.wikidata.org/entity/Q17984894'), ('cName1', 'Winnie the Pooh')]
# [('obj5', 'http://www.wikidata.org/entity/Q191224'), ('cName', 'Walt Disney Pictures'), ('obj6', 'http://www.wikidata.org/entity/Q27151437'), ('cName1', 'Walt Disney Animation Canada')]
# [('obj5', 'http://www.wikidata.org/entity/Q191224'), ('cName', 'Walt Disney Pictures'), ('obj6', 'http://www.wikidata.org/entity/Q3565599'), ('cName1', 'Walt Disney Animation France')]
# [('obj5', 'http://www.wikidata.org/entity/Q19758675'), ('cName', 'Hotstar')]
# [('obj5', 'http://www.wikidata.org/entity/Q19868095'), ('cName', 'Disney XD')]
# [('obj5', 'http://www.wikidata.org/entity/Q19878302'), ('cName', 'Transportation and Ticket Center')]
# [('obj5', 'http://www.wikidata.org/entity/Q198949'), ('cName', 'Disney Magic')]
# [('obj5', 'http://www.wikidata.org/entity/Q198957'), ('cName', 'Disney Wonder')]
# [('obj5', 'http://www.wikidata.org/entity/Q2014847'), ('cName', 'BabyTV')]
# [('obj5', 'http://www.wikidata.org/entity/Q2037777'), ('cName', 'Blip')]
# [('obj5', 'http://www.wikidata.org/entity/Q206521'), ('cName', 'Disneyland Paris')]
# [('obj5', 'http://www.wikidata.org/entity/Q206859'), ('cName', 'Walt Disney World Resort'), ('obj6', 'http://www.wikidata.org/entity/Q17070395'), ('cName1', 'MyMagic+')]
# [('obj5', 'http://www.wikidata.org/entity/Q206859'), ('cName', 'Walt Disney World Resort'), ('obj6', 'http://www.wikidata.org/entity/Q18636714'), ('cName1', 'Disney utilidor system')]
# [('obj5', 'http://www.wikidata.org/entity/Q206859'), ('cName', 'Walt Disney World Resort'), ('obj6', 'http://www.wikidata.org/entity/Q19878302'), ('cName1', 'Transportation and Ticket Center')]
# [('obj5', 'http://www.wikidata.org/entity/Q206859'), ('cName', 'Walt Disney World Resort'), ('obj6', 'http://www.wikidata.org/entity/Q22296075'), ('cName1', "Disney's Magical Express")]
# [('obj5', 'http://www.wikidata.org/entity/Q2081339'), ('cName', 'Disneytoon Studios')]
# [('obj5', 'http://www.wikidata.org/entity/Q2084961'), ('cName', '20th Century Studios Home Entertainment')]
# [('obj5', 'http://www.wikidata.org/entity/Q2104471'), ('cName', 'Disney Music Group')]
# [('obj5', 'http://www.wikidata.org/entity/Q2125296'), ('cName', 'Disney Springs')]
# [('obj5', 'http://www.wikidata.org/entity/Q216611'), ('cName', 'LucasArts')]
# [('obj5', 'http://www.wikidata.org/entity/Q217776'), ('cName', 'ESPN'), ('obj6', 'http://www.wikidata.org/entity/Q3046149'), ('cName1', 'ESPN Extra')]
# [('obj5', 'http://www.wikidata.org/entity/Q217776'), ('cName', 'ESPN'), ('obj6', 'http://www.wikidata.org/entity/Q3259110'), ('cName1', 'Longhorn Network')]
# [('obj5', 'http://www.wikidata.org/entity/Q217776'), ('cName', 'ESPN'), ('obj6', 'http://www.wikidata.org/entity/Q600669'), ('cName1', 'FiveThirtyEight')]
# [('obj5', 'http://www.wikidata.org/entity/Q217776'), ('cName', 'ESPN'), ('obj6', 'http://www.wikidata.org/entity/Q5324239'), ('cName1', 'ESPN Films')]
# [('obj5', 'http://www.wikidata.org/entity/Q217776'), ('cName', 'ESPN'), ('obj6', 'http://www.wikidata.org/entity/Q5434435'), ('cName1', 'Fanzter')]
# [('obj5', 'http://www.wikidata.org/entity/Q217776'), ('cName', 'ESPN'), ('obj6', 'http://www.wikidata.org/entity/Q3046137'), ('cName1', 'ESPN.com')]
# [('obj5', 'http://www.wikidata.org/entity/Q217776'), ('cName', 'ESPN'), ('obj6', 'http://www.wikidata.org/entity/Q3046181'), ('cName1', 'ESPN FC')]
# [('obj5', 'http://www.wikidata.org/entity/Q217776'), ('cName', 'ESPN'), ('obj6', 'http://www.wikidata.org/entity/Q16911414'), ('cName1', 'Grantland')]
# [('obj5', 'http://www.wikidata.org/entity/Q217776'), ('cName', 'ESPN'), ('obj6', 'http://www.wikidata.org/entity/Q2887818'), ('cName1', 'ESPN3')]
# [('obj5', 'http://www.wikidata.org/entity/Q217776'), ('cName', 'ESPN'), ('obj6', 'http://www.wikidata.org/entity/Q16558744'), ('cName1', 'ESPN 2 (Brasil)')]
# [('obj5', 'http://www.wikidata.org/entity/Q217776'), ('cName', 'ESPN'), ('obj6', 'http://www.wikidata.org/entity/Q5816263'), ('cName1', 'ESPN 2 (Andino)')]
# [('obj5', 'http://www.wikidata.org/entity/Q217776'), ('cName', 'ESPN'), ('obj6', 'http://www.wikidata.org/entity/Q5816271'), ('cName1', 'ESPN 3 (Latinoamérica)')]
# [('obj5', 'http://www.wikidata.org/entity/Q217776'), ('cName', 'ESPN'), ('obj6', 'http://www.wikidata.org/entity/Q6167975'), ('cName1', "Jayski's Silly Season Site")]
# [('obj5', 'http://www.wikidata.org/entity/Q217776'), ('cName', 'ESPN'), ('obj6', 'http://www.wikidata.org/entity/Q8771352'), ('cName1', 'ESPN+ (Latin America)')]
# [('obj5', 'http://www.wikidata.org/entity/Q22079532'), ('cName', 'The Walt Disney Company Argentina')]
# [('obj5', 'http://www.wikidata.org/entity/Q22079560'), ('cName', 'YourTV')]
# [('obj5', 'http://www.wikidata.org/entity/Q22092344'), ('cName', 'Star Wars')]
# [('obj5', 'http://www.wikidata.org/entity/Q2216535'), ('cName', 'Walt Disney Studios')]
# [('obj5', 'http://www.wikidata.org/entity/Q22296075'), ('cName', "Disney's Magical Express")]
# [('obj5', 'http://www.wikidata.org/entity/Q2260281'), ('cName', 'Disney Channel Italy')]
# [('obj5', 'http://www.wikidata.org/entity/Q2273453'), ('cName', 'STAR World')]
# [('obj5', 'http://www.wikidata.org/entity/Q2299634'), ('cName', 'National Geographic People')]
# [('obj5', 'http://www.wikidata.org/entity/Q23022746'), ('cName', 'Star Utsav Movies')]
# [('obj5', 'http://www.wikidata.org/entity/Q23022864'), ('cName', 'Viceland')]
# [('obj5', 'http://www.wikidata.org/entity/Q2340292'), ('cName', 'Euro Disney S.C.A.')]
# [('obj5', 'http://www.wikidata.org/entity/Q2376669'), ('cName', 'Disney Junior (Spain)')]
# [('obj5', 'http://www.wikidata.org/entity/Q2377604'), ('cName', 'Disney XD')]
# [('obj5', 'http://www.wikidata.org/entity/Q2378052'), ('cName', 'Disney Channel Spain')]
# [('obj5', 'http://www.wikidata.org/entity/Q23837644'), ('cName', 'Endemol Shine Group')]
# [('obj5', 'http://www.wikidata.org/entity/Q2405352'), ('cName', 'ImageMovers')]
# [('obj5', 'http://www.wikidata.org/entity/Q242446'), ('cName', 'Lucasfilm'), ('obj6', 'http://www.wikidata.org/entity/Q2562640'), ('cName1', 'Indiana Jones')]
# [('obj5', 'http://www.wikidata.org/entity/Q242446'), ('cName', 'Lucasfilm'), ('obj6', 'http://www.wikidata.org/entity/Q22092344'), ('cName1', 'Star Wars')]
# [('obj5', 'http://www.wikidata.org/entity/Q24273005'), ('cName', 'thewaltdisneycompany.com')]
# [('obj5', 'http://www.wikidata.org/entity/Q2501552'), ('cName', 'Disneynature')]
# [('obj5', 'http://www.wikidata.org/entity/Q25377492'), ('cName', 'The Walt Disney Company Australia')]
# [('obj5', 'http://www.wikidata.org/entity/Q25384903'), ('cName', 'The Walt Disney Company China')]
# [('obj5', 'http://www.wikidata.org/entity/Q2562640'), ('cName', 'Indiana Jones')]
# [('obj5', 'http://www.wikidata.org/entity/Q2592540'), ('cName', 'Disney Channel Netherlands & Flanders')]
# [('obj5', 'http://www.wikidata.org/entity/Q264058'), ('cName', 'H2')]
# [('obj5', 'http://www.wikidata.org/entity/Q2703822'), ('cName', 'Skywalker Sound')]
# [('obj5', 'http://www.wikidata.org/entity/Q27151437'), ('cName', 'Walt Disney Animation Canada')]
# [('obj5', 'http://www.wikidata.org/entity/Q2717612'), ('cName', '20th Century Fox Television')]
# [('obj5', 'http://www.wikidata.org/entity/Q27186707'), ('cName', 'Jumbo Pictures')]
# [('obj5', 'http://www.wikidata.org/entity/Q2734852'), ('cName', 'GMTV')]
# [('obj5', 'http://www.wikidata.org/entity/Q2737435'), ('cName', 'Disney–ABC Domestic Television')]
# [('obj5', 'http://www.wikidata.org/entity/Q277561'), ('cName', 'A&E')]
# [('obj5', 'http://www.wikidata.org/entity/Q2777866'), ('cName', 'DisneyQuest')]
# [('obj5', 'http://www.wikidata.org/entity/Q2813838'), ('cName', '20,000 Leagues Under the Sea: Submarine Voyage')]
# [('obj5', 'http://www.wikidata.org/entity/Q2814799'), ('cName', '20th Television')]
# [('obj5', 'http://www.wikidata.org/entity/Q28457298'), ('cName', 'FoxNext')]
# [('obj5', 'http://www.wikidata.org/entity/Q287149'), ('cName', 'Freeform')]
# [('obj5', 'http://www.wikidata.org/entity/Q287171'), ('cName', 'ABC News'), ('obj6', 'http://www.wikidata.org/entity/Q600669'), ('cName1', 'FiveThirtyEight')]
# [('obj5', 'http://www.wikidata.org/entity/Q2887818'), ('cName', 'ESPN3')]
# [('obj5', 'http://www.wikidata.org/entity/Q29015971'), ('cName', 'Disney Streaming Services')]
# [('obj5', 'http://www.wikidata.org/entity/Q2912731'), ('cName', 'Disney Channel (Israel)')]
# [('obj5', 'http://www.wikidata.org/entity/Q2915959'), ('cName', "Disney's River Country")]
# [('obj5', 'http://www.wikidata.org/entity/Q2937387'), ('cName', 'Capital Disney')]
# [('obj5', 'http://www.wikidata.org/entity/Q2944088'), ('cName', 'Pixar Canada')]
# [('obj5', 'http://www.wikidata.org/entity/Q2994210'), ('cName', 'STAR Sports 3')]
# [('obj5', 'http://www.wikidata.org/entity/Q3030351'), ('cName', 'Disney-ABC Cable Network Group')]
# [('obj5', 'http://www.wikidata.org/entity/Q3030368'), ('cName', 'Disney Channel')]
# [('obj5', 'http://www.wikidata.org/entity/Q3030369'), ('cName', 'Disney Channel')]
# [('obj5', 'http://www.wikidata.org/entity/Q3030374'), ('cName', 'Disney Channel Deutschland')]
# [('obj5', 'http://www.wikidata.org/entity/Q3030385'), ('cName', 'Disney Channel')]
# [('obj5', 'http://www.wikidata.org/entity/Q3030399'), ('cName', 'Disney Cinemagic')]
# [('obj5', 'http://www.wikidata.org/entity/Q3030405'), ('cName', 'Disney Direct')]
# [('obj5', 'http://www.wikidata.org/entity/Q3030406'), ('cName', 'Disney Development Company')]
# [('obj5', 'http://www.wikidata.org/entity/Q3030410'), ('cName', 'Disney Consumer Products')]
# [('obj5', 'http://www.wikidata.org/entity/Q3030411'), ('cName', 'Disney Editions')]
# [('obj5', 'http://www.wikidata.org/entity/Q3030429'), ('cName', 'Disney Institute')]
# [('obj5', 'http://www.wikidata.org/entity/Q3030432'), ('cName', 'Disney Interactive')]
# [('obj5', 'http://www.wikidata.org/entity/Q3030440'), ('cName', 'Disney Junior')]
# [('obj5', 'http://www.wikidata.org/entity/Q3030445'), ('cName', 'Disney Platform Distribution')]
# [('obj5', 'http://www.wikidata.org/entity/Q3030447'), ('cName', 'Disney Media Networks')]
# [('obj5', 'http://www.wikidata.org/entity/Q3030458'), ('cName', 'Disney Mobile')]
# [('obj5', 'http://www.wikidata.org/entity/Q3030460'), ('cName', 'Disney Press')]
# [('obj5', 'http://www.wikidata.org/entity/Q3030485'), ('cName', 'Disney Vacation Club')]
# [('obj5', 'http://www.wikidata.org/entity/Q3030499'), ('cName', 'Disneyland, Inc.')]
# [('obj5', 'http://www.wikidata.org/entity/Q3030506'), ('cName', 'Disneytown')]
# [('obj5', 'http://www.wikidata.org/entity/Q3030511'), ('cName', 'Disneyland Railroad')]
# [('obj5', 'http://www.wikidata.org/entity/Q3039254'), ('cName', 'Dream Quest Images')]
# [('obj5', 'http://www.wikidata.org/entity/Q3046137'), ('cName', 'ESPN.com')]
# [('obj5', 'http://www.wikidata.org/entity/Q3046149'), ('cName', 'ESPN Extra')]
# [('obj5', 'http://www.wikidata.org/entity/Q3046171'), ('cName', 'ESPN Zone')]
# [('obj5', 'http://www.wikidata.org/entity/Q3046173'), ('cName', 'ESPN Star Sports')]
# [('obj5', 'http://www.wikidata.org/entity/Q3046181'), ('cName', 'ESPN FC')]
# [('obj5', 'http://www.wikidata.org/entity/Q30492190'), ('cName', 'Nat Geo Kids (Latin America)')]
# [('obj5', 'http://www.wikidata.org/entity/Q30566378'), ('cName', 'A&E')]
# [('obj5', 'http://www.wikidata.org/entity/Q3064766'), ('cName', 'Fall Line Studios')]
# [('obj5', 'http://www.wikidata.org/entity/Q306585'), ('cName', 'Channel V')]
# [('obj5', 'http://www.wikidata.org/entity/Q30919172'), ('cName', 'History (Latinoamérica)')]
# [('obj5', 'http://www.wikidata.org/entity/Q3094998'), ('cName', 'Gamestar')]
# [('obj5', 'http://www.wikidata.org/entity/Q3100510'), ('cName', 'Hong Kong International Theme Parks')]
# [('obj5', 'http://www.wikidata.org/entity/Q313173'), ('cName', 'Toon Disney')]
# [('obj5', 'http://www.wikidata.org/entity/Q313621'), ('cName', 'Disney Junior')]
# [('obj5', 'http://www.wikidata.org/entity/Q3146319'), ('cName', 'Hotels of The Walt Disney Company')]
# [('obj5', 'http://www.wikidata.org/entity/Q3150108'), ('cName', 'Indiana Jones Adventure')]
# [('obj5', 'http://www.wikidata.org/entity/Q3150870'), ('cName', 'Infoseek')]
# [('obj5', 'http://www.wikidata.org/entity/Q3177799'), ('cName', 'Jetix Europe')]
# [('obj5', 'http://www.wikidata.org/entity/Q3177801'), ('cName', 'Jetix International')]
# [('obj5', 'http://www.wikidata.org/entity/Q3189915'), ('cName', 'Cartoon Pizza')]
# [('obj5', 'http://www.wikidata.org/entity/Q3189994'), ('cName', 'Junction Point Studios')]
# [('obj5', 'http://www.wikidata.org/entity/Q3191359'), ('cName', 'KESN')]
# [('obj5', 'http://www.wikidata.org/entity/Q3195479'), ('cName', 'Kerpoof')]
# [('obj5', 'http://www.wikidata.org/entity/Q3238409'), ('cName', 'Lifetime Entertainment Services')]
# [('obj5', 'http://www.wikidata.org/entity/Q3259110'), ('cName', 'Longhorn Network')]
# [('obj5', 'http://www.wikidata.org/entity/Q3282004'), ('cName', 'Tiger Aspect Productions')]
# [('obj5', 'http://www.wikidata.org/entity/Q32854807'), ('cName', 'Endemol Shine Iberia')]
# [('obj5', 'http://www.wikidata.org/entity/Q3299645'), ('cName', 'Disney Junior')]
# [('obj5', 'http://www.wikidata.org/entity/Q3327964'), ('cName', 'The Muppets Studio')]
# [('obj5', 'http://www.wikidata.org/entity/Q3336288'), ('cName', 'Nat Geo Wild')]
# [('obj5', 'http://www.wikidata.org/entity/Q334671'), ('cName', 'Disney Channel Scandinavia')]
# [('obj5', 'http://www.wikidata.org/entity/Q3366991'), ('cName', 'Partners Federal Credit Union')]
# [('obj5', 'http://www.wikidata.org/entity/Q3433822'), ('cName', 'Crime & Investigation Network')]
# [('obj5', 'http://www.wikidata.org/entity/Q3492330'), ('cName', 'Endemol Australia')]
# [('obj5', 'http://www.wikidata.org/entity/Q3497261'), ('cName', 'Starwave')]
# [('obj5', 'http://www.wikidata.org/entity/Q3497756'), ('cName', 'Steamboat Ventures')]
# [('obj5', 'http://www.wikidata.org/entity/Q3523270'), ('cName', 'The Walt Disney Company France')]
# [('obj5', 'http://www.wikidata.org/entity/Q3523271'), ('cName', 'The Walt Disney Company CIS')]
# [('obj5', 'http://www.wikidata.org/entity/Q3523272'), ('cName', 'The Walt Disney Company Southeast Asia')]
# [('obj5', 'http://www.wikidata.org/entity/Q3523273'), ('cName', 'The Walt Disney Company India')]
# [('obj5', 'http://www.wikidata.org/entity/Q3523275'), ('cName', 'The Walt Disney Company Italy')]
# [('obj5', 'http://www.wikidata.org/entity/Q3556742'), ('cName', 'Viajar')]
# [('obj5', 'http://www.wikidata.org/entity/Q3561108'), ('cName', 'Vista Federal Credit Union')]
# [('obj5', 'http://www.wikidata.org/entity/Q3564667'), ('cName', 'WEPN')]
# [('obj5', 'http://www.wikidata.org/entity/Q3564732'), ('cName', 'WMVP')]
# [('obj5', 'http://www.wikidata.org/entity/Q3565599'), ('cName', 'Walt Disney Animation France')]
# [('obj5', 'http://www.wikidata.org/entity/Q3565606'), ('cName', 'Disney Software')]
# [('obj5', 'http://www.wikidata.org/entity/Q3565607'), ('cName', 'Disney Educational Productions')]
# [('obj5', 'http://www.wikidata.org/entity/Q3565612'), ('cName', 'Walt Disney International')]
# [('obj5', 'http://www.wikidata.org/entity/Q3565620'), ('cName', 'Walt Disney Publications')]
# [('obj5', 'http://www.wikidata.org/entity/Q3565621'), ('cName', 'The Walt Disney Company (Japan)')]
# [('obj5', 'http://www.wikidata.org/entity/Q3565623'), ('cName', 'Walt Disney Music Company, Inc.')]
# [('obj5', 'http://www.wikidata.org/entity/Q3565635'), ('cName', 'Walt Disney World Casting Center')]
# [('obj5', 'http://www.wikidata.org/entity/Q3565637'), ('cName', 'Walt Disney Parks and Resorts U.S.')]
# [('obj5', 'http://www.wikidata.org/entity/Q3565642'), ('cName', 'Walt Disney Television')]
# [('obj5', 'http://www.wikidata.org/entity/Q3628946'), ('cName', 'Star Sports')]
# [('obj5', 'http://www.wikidata.org/entity/Q3630152'), ('cName', 'STAR Utsav')]
# [('obj5', 'http://www.wikidata.org/entity/Q3631478'), ('cName', 'Star Plus')]
# [('obj5', 'http://www.wikidata.org/entity/Q3631491'), ('cName', 'STAR Gold')]
# [('obj5', 'http://www.wikidata.org/entity/Q38072167'), ('cName', 'FX Movies (Latin America)')]
# [('obj5', 'http://www.wikidata.org/entity/Q390223'), ('cName', 'Club Penguin')]
# [('obj5', 'http://www.wikidata.org/entity/Q39058665'), ('cName', 'Star Bharat')]
# [('obj5', 'http://www.wikidata.org/entity/Q4132097'), ('cName', 'Military History')]
# [('obj5', 'http://www.wikidata.org/entity/Q4132994'), ('cName', 'Disney Theatrical Group')]
# [('obj5', 'http://www.wikidata.org/entity/Q420947'), ('cName', 'Disney Cruise Line'), ('obj6', 'http://www.wikidata.org/entity/Q1228989'), ('cName1', 'Disney Dream')]
# [('obj5', 'http://www.wikidata.org/entity/Q420947'), ('cName', 'Disney Cruise Line'), ('obj6', 'http://www.wikidata.org/entity/Q198949'), ('cName1', 'Disney Magic')]
# [('obj5', 'http://www.wikidata.org/entity/Q420947'), ('cName', 'Disney Cruise Line'), ('obj6', 'http://www.wikidata.org/entity/Q1228992'), ('cName1', 'Disney Fantasy')]
# [('obj5', 'http://www.wikidata.org/entity/Q420947'), ('cName', 'Disney Cruise Line'), ('obj6', 'http://www.wikidata.org/entity/Q198957'), ('cName1', 'Disney Wonder')]
# [('obj5', 'http://www.wikidata.org/entity/Q434841'), ('cName', '20th Century Studios'), ('obj6', 'http://www.wikidata.org/entity/Q17018738'), ('cName1', 'Kingsman')]
# [('obj5', 'http://www.wikidata.org/entity/Q45001184'), ('cName', 'National Geographic Kids Abu Dhabi')]
# [('obj5', 'http://www.wikidata.org/entity/Q465449'), ('cName', 'Miramax'), ('obj6', 'http://www.wikidata.org/entity/Q908662'), ('cName1', 'Dimension Films')]
# [('obj5', 'http://www.wikidata.org/entity/Q46996011'), ('cName', 'ESPN+')]
# [('obj5', 'http://www.wikidata.org/entity/Q47481944'), ('cName', 'Endemol Shine Israel')]
# [('obj5', 'http://www.wikidata.org/entity/Q4837590'), ('cName', 'babble.com')]
# [('obj5', 'http://www.wikidata.org/entity/Q49402184'), ('cName', 'Fox Movies')]
# [('obj5', 'http://www.wikidata.org/entity/Q4947547'), ('cName', 'Bossa Studios')]
# [('obj5', 'http://www.wikidata.org/entity/Q495107'), ('cName', 'Fox Life')]
# [('obj5', 'http://www.wikidata.org/entity/Q497155'), ('cName', 'Touchstone Pictures')]
# [('obj5', 'http://www.wikidata.org/entity/Q5072463'), ('cName', 'Channel [V] Philippines')]
# [('obj5', 'http://www.wikidata.org/entity/Q50991720'), ('cName', 'MovieCo')]
# [('obj5', 'http://www.wikidata.org/entity/Q51595207'), ('cName', 'list of production companies owned by the American Broadcasting Company')]
# [('obj5', 'http://www.wikidata.org/entity/Q5185160'), ('cName', 'Crime & Investigation Network')]
# [('obj5', 'http://www.wikidata.org/entity/Q5185161'), ('cName', 'Crime & Investigation Network Asia')]
# [('obj5', 'http://www.wikidata.org/entity/Q5270612'), ('cName', 'Fox Life India')]
# [('obj5', 'http://www.wikidata.org/entity/Q5282418'), ('cName', 'Disney Channel')]
# [('obj5', 'http://www.wikidata.org/entity/Q5282427'), ('cName', 'Disney Channel Malaysia')]
# [('obj5', 'http://www.wikidata.org/entity/Q5282435'), ('cName', 'Disney Character Voices International')]
# [('obj5', 'http://www.wikidata.org/entity/Q5282441'), ('cName', 'Disney D23')]
# [('obj5', 'http://www.wikidata.org/entity/Q5282458'), ('cName', 'Disney Junior')]
# [('obj5', 'http://www.wikidata.org/entity/Q5324239'), ('cName', 'ESPN Films')]
# [('obj5', 'http://www.wikidata.org/entity/Q5376047'), ('cName', 'Endemol Shine UK')]
# [('obj5', 'http://www.wikidata.org/entity/Q5427400'), ('cName', 'Fox Comedy Portugal')]
# [('obj5', 'http://www.wikidata.org/entity/Q5434435'), ('cName', 'Fanzter')]
# [('obj5', 'http://www.wikidata.org/entity/Q5476678'), ('cName', 'Fox Crime Asia')]
# [('obj5', 'http://www.wikidata.org/entity/Q5476702'), ('cName', 'Fox Filipino')]
# [('obj5', 'http://www.wikidata.org/entity/Q5476806'), ('cName', 'Fox Life Greece')]
# [('obj5', 'http://www.wikidata.org/entity/Q5476820'), ('cName', 'Fox Movie Channel')]
# [('obj5', 'http://www.wikidata.org/entity/Q5476840'), ('cName', 'Fox Movies Premium')]
# [('obj5', 'http://www.wikidata.org/entity/Q5476977'), ('cName', 'Fox Star Studios')]
# [('obj5', 'http://www.wikidata.org/entity/Q54857'), ('cName', 'Radio Disney')]
# [('obj5', 'http://www.wikidata.org/entity/Q55830205'), ('cName', 'Jetix CEE')]
# [('obj5', 'http://www.wikidata.org/entity/Q5816263'), ('cName', 'ESPN 2 (Andino)')]
# [('obj5', 'http://www.wikidata.org/entity/Q5816271'), ('cName', 'ESPN 3 (Latinoamérica)')]
# [('obj5', 'http://www.wikidata.org/entity/Q5930877'), ('cName', 'Jetix (Spain)')]
# [('obj5', 'http://www.wikidata.org/entity/Q600669'), ('cName', 'FiveThirtyEight')]
# [('obj5', 'http://www.wikidata.org/entity/Q6145466'), ('cName', 'The Walt Disney Company Iberia')]
# [('obj5', 'http://www.wikidata.org/entity/Q6148912'), ('cName', 'Toon Disney Spain')]
# [('obj5', 'http://www.wikidata.org/entity/Q6167975'), ('cName', "Jayski's Silly Season Site")]
# [('obj5', 'http://www.wikidata.org/entity/Q622329'), ('cName', 'The Biography Channel')]
# [('obj5', 'http://www.wikidata.org/entity/Q6310201'), ('cName', 'History TV18')]
# [('obj5', 'http://www.wikidata.org/entity/Q634019'), ('cName', '20th Century Animation')]
# [('obj5', 'http://www.wikidata.org/entity/Q635278'), ('cName', 'Disney Cinemagic')]
# [('obj5', 'http://www.wikidata.org/entity/Q637164'), ('cName', 'The Baby Einstein Company')]
# [('obj5', 'http://www.wikidata.org/entity/Q651228'), ('cName', 'FX')]
# [('obj5', 'http://www.wikidata.org/entity/Q654073'), ('cName', 'Walt Disney Television')]
# [('obj5', 'http://www.wikidata.org/entity/Q6545534'), ('cName', 'LMN')]
# [('obj5', 'http://www.wikidata.org/entity/Q672664'), ('cName', 'Black Rock Studio')]
# [('obj5', 'http://www.wikidata.org/entity/Q6739276'), ('cName', 'Disney Digital Network')]
# [('obj5', 'http://www.wikidata.org/entity/Q684994'), ('cName', 'Super RTL')]
# [('obj5', 'http://www.wikidata.org/entity/Q724613'), ('cName', 'Buena Vista International Television')]
# [('obj5', 'http://www.wikidata.org/entity/Q7280765'), ('cName', 'Radio Disney Brasil')]
# [('obj5', 'http://www.wikidata.org/entity/Q7340286'), ('cName', 'Rob Kidd')]
# [('obj5', 'http://www.wikidata.org/entity/Q738088'), ('cName', '24Kitchen')]
# [('obj5', 'http://www.wikidata.org/entity/Q7394683'), ('cName', 'STAR World India')]
# [('obj5', 'http://www.wikidata.org/entity/Q7394684'), ('cName', 'STAR World Philippines')]
# [('obj5', 'http://www.wikidata.org/entity/Q7426051'), ('cName', 'Satellite News Channel')]
# [('obj5', 'http://www.wikidata.org/entity/Q746676'), ('cName', 'Industrial Light & Magic')]
# [('obj5', 'http://www.wikidata.org/entity/Q7747662'), ('cName', "Disney's The Little Mermaid")]
# [('obj5', 'http://www.wikidata.org/entity/Q7949486'), ('cName', 'WFRO')]
# [('obj5', 'http://www.wikidata.org/entity/Q83723'), ('cName', 'A&E Networks'), ('obj6', 'http://www.wikidata.org/entity/Q622329'), ('cName1', 'The Biography Channel')]
# [('obj5', 'http://www.wikidata.org/entity/Q83723'), ('cName', 'A&E Networks'), ('obj6', 'http://www.wikidata.org/entity/Q277561'), ('cName1', 'A&E')]
# [('obj5', 'http://www.wikidata.org/entity/Q83723'), ('cName', 'A&E Networks'), ('obj6', 'http://www.wikidata.org/entity/Q264058'), ('cName1', 'H2')]
# [('obj5', 'http://www.wikidata.org/entity/Q83723'), ('cName', 'A&E Networks'), ('obj6', 'http://www.wikidata.org/entity/Q6310201'), ('cName1', 'History TV18')]
# [('obj5', 'http://www.wikidata.org/entity/Q83723'), ('cName', 'A&E Networks'), ('obj6', 'http://www.wikidata.org/entity/Q6545534'), ('cName1', 'LMN')]
# [('obj5', 'http://www.wikidata.org/entity/Q83723'), ('cName', 'A&E Networks'), ('obj6', 'http://www.wikidata.org/entity/Q23022864'), ('cName1', 'Viceland')]
# [('obj5', 'http://www.wikidata.org/entity/Q83723'), ('cName', 'A&E Networks'), ('obj6', 'http://www.wikidata.org/entity/Q30566378'), ('cName1', 'A&E')]
# [('obj5', 'http://www.wikidata.org/entity/Q83723'), ('cName', 'A&E Networks'), ('obj6', 'http://www.wikidata.org/entity/Q30919172'), ('cName1', 'History (Latinoamérica)')]
# [('obj5', 'http://www.wikidata.org/entity/Q83723'), ('cName', 'A&E Networks'), ('obj6', 'http://www.wikidata.org/entity/Q17619901'), ('cName1', 'Lifetime Latinoamérica')]
# [('obj5', 'http://www.wikidata.org/entity/Q83723'), ('cName', 'A&E Networks'), ('obj6', 'http://www.wikidata.org/entity/Q3238409'), ('cName1', 'Lifetime Entertainment Services')]
# [('obj5', 'http://www.wikidata.org/entity/Q83723'), ('cName', 'A&E Networks'), ('obj6', 'http://www.wikidata.org/entity/Q3433822'), ('cName1', 'Crime & Investigation Network')]
# [('obj5', 'http://www.wikidata.org/entity/Q83723'), ('cName', 'A&E Networks'), ('obj6', 'http://www.wikidata.org/entity/Q5185160'), ('cName1', 'Crime & Investigation Network')]
# [('obj5', 'http://www.wikidata.org/entity/Q83723'), ('cName', 'A&E Networks'), ('obj6', 'http://www.wikidata.org/entity/Q5185161'), ('cName1', 'Crime & Investigation Network Asia')]
# [('obj5', 'http://www.wikidata.org/entity/Q83723'), ('cName', 'A&E Networks'), ('obj6', 'http://www.wikidata.org/entity/Q9693853'), ('cName1', 'History (European TV channel)')]
# [('obj5', 'http://www.wikidata.org/entity/Q849284'), ('cName', 'El Capitan Theatre')]
# [('obj5', 'http://www.wikidata.org/entity/Q8771352'), ('cName', 'ESPN+ (Latin America)')]
# [('obj5', 'http://www.wikidata.org/entity/Q885885'), ('cName', 'Blue Sky Studios')]
# [('obj5', 'http://www.wikidata.org/entity/Q9004339'), ('cName', 'History en Español')]
# [('obj5', 'http://www.wikidata.org/entity/Q902959'), ('cName', 'Times Square Studios')]
# [('obj5', 'http://www.wikidata.org/entity/Q908662'), ('cName', 'Dimension Films')]
# [('obj5', 'http://www.wikidata.org/entity/Q919514'), ('cName', 'Fox Studios Australia')]
# [('obj5', 'http://www.wikidata.org/entity/Q953040'), ('cName', 'Searchlight Pictures')]
# [('obj5', 'http://www.wikidata.org/entity/Q9693853'), ('cName', 'History (European TV channel)')]
# [('obj5', 'http://www.wikidata.org/entity/Q969695'), ('cName', 'Mickey Mouse')]
# [('obj5', 'http://www.wikidata.org/entity/Q973987'), ('cName', 'Shanghai Disney Resort')]
# 323

# %% [markdown]
# **Answer 2**
#
# I can define the BGP for the owned company of a business
#
# ```
# SELECT DISTINCT ?obj5 ?cName ?obj6 ?cName1
# WHERE {
#
# ?company wdt:P31 wd:Q4830453  .
# ?company wdt:P1830+ ?obj5 . #owner of
#
# ?obj5 <http://schema.org/name> ?cName .
#
# OPTIONAL{
# ?obj5 wdt:P1830+ ?obj6 .
# ?obj6 <http://schema.org/name> ?cName1 .
# }
#
# }
# ORDER BY ASC(?obj5)
#
# ```
#
# The simpler version is
#
# ```
# SELECT DISTINCT ?obj5 ?cName ?obj6 ?cName1
# WHERE {
#
# ?company wdt:P31 wd:Q4830453  .
# ?company wdt:P1830 ?obj5 . #owner of
#
# }
# ORDER BY ASC(?obj5)
#
# ```
# ------------------

# %% [markdown]
# **3 - Is there some company that owns companies in other countries?**
#
# I try to search for the answer using the simpler version.

# %%
queryString = """
SELECT DISTINCT ?cName ?cnName ?cName1 ?cnName1
WHERE {

# ?company wdt:P17 ?country .
# ?company wdt:P31 wd:Q4830453  . 

# ?company wdt:P1830 ?obj5 . #owner of
# ?obj5 wdt:P17 ?country1.

# ?obj5 <http://schema.org/name> ?cName1 .
# ?company <http://schema.org/name> ?cName .
# ?country <http://schema.org/name> ?cnName .
# ?country1 <http://schema.org/name> ?cnName1 .

FILTER (?country1 != ?country)
} 
LIMIT 30
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('cName', 'AG für Verkehrswesen'), ('cnName', 'German Reich'), ('cName1', 'Ostpreußische Kleinbahnen'), ('cnName1', 'Russia')]
# [('cName', 'AG für Verkehrswesen'), ('cnName', 'German Reich'), ('cName1', 'Halle-Hettstedter Eisenbahn-Gesellschaft'), ('cnName1', 'German Democratic Republic')]
# [('cName', 'AG für Verkehrswesen'), ('cnName', 'German Reich'), ('cName1', 'Industriebahn AG'), ('cnName1', 'Germany')]
# [('cName', 'AG für Verkehrswesen'), ('cnName', 'German Reich'), ('cName1', 'Bremisch-Hannoversche Kleinbahn'), ('cnName1', 'Germany')]
# [('cName', 'AG für Verkehrswesen'), ('cnName', 'German Reich'), ('cName1', 'Württembergische Nebenbahnen'), ('cnName1', 'Germany')]
# [('cName', 'AG für Verkehrswesen'), ('cnName', 'German Reich'), ('cName1', 'Butzbach-Licher Eisenbahn'), ('cnName1', 'Germany')]
# [('cName', 'AG für Verkehrswesen'), ('cnName', 'German Reich'), ('cName1', 'Frankfurt-Königsteiner Eisenbahn'), ('cnName1', 'Germany')]
# [('cName', 'AG für Verkehrswesen'), ('cnName', 'German Reich'), ('cName1', 'Teutoburger Wald-Eisenbahn'), ('cnName1', 'Germany')]
# [('cName', 'Allgemeine Deutsche Kleinbahn-Gesellschaft AG'), ('cnName', 'German Reich'), ('cName1', 'Teutoburger Wald-Eisenbahn'), ('cnName1', 'Germany')]
# [('cName', 'AG für Verkehrswesen'), ('cnName', 'German Reich'), ('cName1', 'Braunschweig-Schöninger Eisenbahn'), ('cnName1', 'Germany')]
# [('cName', 'AG für Verkehrswesen'), ('cnName', 'German Reich'), ('cName1', 'Garte Valley Railway'), ('cnName1', 'Germany')]
# [('cName', 'Allgemeine Deutsche Kleinbahn-Gesellschaft AG'), ('cnName', 'German Reich'), ('cName1', 'Rinteln-Stadthagen railway line'), ('cnName1', 'Germany')]
# [('cName', 'AG für Verkehrswesen'), ('cnName', 'German Reich'), ('cName1', 'Kassel-Naumburger Eisenbahn'), ('cnName1', 'Germany')]
# [('cName', 'AG für Verkehrswesen'), ('cnName', 'German Reich'), ('cName1', 'Nassau Light Railway'), ('cnName1', 'Germany')]
# [('cName', 'Allgemeine Deutsche Kleinbahn-Gesellschaft AG'), ('cnName', 'German Reich'), ('cName1', 'Nassau Light Railway'), ('cnName1', 'Germany')]
# [('cName', 'AG für Verkehrswesen'), ('cnName', 'German Reich'), ('cName1', 'Farge-Vegesacker Eisenbahn'), ('cnName1', 'Germany')]
# [('cName', 'AG für Verkehrswesen'), ('cnName', 'German Reich'), ('cName1', 'Hildesheim-Peiner Kreis-Eisenbahn-Gesellschaft'), ('cnName1', 'Germany')]
# [('cName', 'AG für Verkehrswesen'), ('cnName', 'German Reich'), ('cName1', 'Kiel–Schönberger Eisenbahn'), ('cnName1', 'Germany')]
# [('cName', 'AG für Verkehrswesen'), ('cnName', 'German Reich'), ('cName1', 'Kleinbahn Kiel-Segeberg'), ('cnName1', 'Germany')]
# [('cName', 'AG für Verkehrswesen'), ('cnName', 'German Reich'), ('cName1', 'Moselbahn GmbH'), ('cnName1', 'Germany')]
# [('cName', 'AG für Verkehrswesen'), ('cnName', 'German Reich'), ('cName1', 'Freien Grunder Eisenbahn'), ('cnName1', 'Germany')]
# [('cName', 'AG für Verkehrswesen'), ('cnName', 'German Reich'), ('cName1', 'Oschersleben-Schöninger Eisenbahn-Gesellschaft'), ('cnName1', 'Germany')]
# [('cName', 'AG für Verkehrswesen'), ('cnName', 'German Reich'), ('cName1', 'Former railway line Zielona Góra - Szprotawa'), ('cnName1', 'Poland')]
# [('cName', 'AG für Verkehrswesen'), ('cnName', 'German Reich'), ('cName1', 'Trachenberg-Militscher Kreisbahn'), ('cnName1', 'Poland')]
# [('cName', 'AG für Verkehrswesen'), ('cnName', 'German Reich'), ('cName1', 'Eulengebirgsbahn'), ('cnName1', 'Poland')]
# [('cName', 'Électricité de France'), ('cnName', 'France'), ('cName1', 'EDF Energy'), ('cnName1', 'United Kingdom')]
# [('cName', 'STMicroelectronics'), ('cnName', 'France'), ('cName1', 'Genesis Microchip'), ('cnName1', 'Canada')]
# [('cName', 'Bernheim-Jeune'), ('cnName', 'France'), ('cName1', 'Little Lange'), ('cnName1', 'Germany')]
# [('cName', 'Bernheim-Jeune'), ('cnName', 'France'), ('cName1', 'The Old Mill'), ('cnName1', 'United States of America')]
# [('cName', 'Électricité de France'), ('cnName', 'France'), ('cName1', 'Luminus'), ('cnName1', 'Belgium')]
# 30

# %% [markdown]
# restricting to USA Q30, UK Q145, and Canada Q16

# %%
queryString = """
SELECT DISTINCT ?cName ?cnName ?cName1 ?cnName1
WHERE {

# ?company wdt:P17 ?country .
# ?company wdt:P31 wd:Q4830453  . 

# ?company wdt:P1830 ?obj5 . #owner of
# ?obj5 wdt:P17 ?country1.

# ?obj5 <http://schema.org/name> ?cName1 .
# ?company <http://schema.org/name> ?cName .
# ?country <http://schema.org/name> ?cnName .
# ?country1 <http://schema.org/name> ?cnName1 .

FILTER (?country1 != ?country)
FILTER (?country = wd:Q30 || ?country = wd:Q145 || ?country = wd:Q16)
} 
ORDER BY ASC(?cName)
LIMIT 70
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('cName', '3G Capital'), ('cnName', 'United States of America'), ('cName1', 'Lojas Americanas'), ('cnName1', 'Brazil')]
# [('cName', '3G Capital'), ('cnName', 'United States of America'), ('cName1', 'América Latina Logística'), ('cnName1', 'Brazil')]
# [('cName', '3G Capital'), ('cnName', 'United States of America'), ('cName1', 'Restaurant Brands International'), ('cnName1', 'Canada')]
# [('cName', 'A&E Networks'), ('cnName', 'United States of America'), ('cName1', 'Crime & Investigation Network Asia'), ('cnName1', 'Singapore')]
# [('cName', 'A&E Networks'), ('cnName', 'United States of America'), ('cName1', 'Crime & Investigation Network'), ('cnName1', 'United Kingdom')]
# [('cName', 'A&E Networks'), ('cnName', 'United States of America'), ('cName1', 'History TV18'), ('cnName1', 'India')]
# [('cName', 'A&E Networks'), ('cnName', 'United States of America'), ('cName1', 'H2'), ('cnName1', 'Brazil')]
# [('cName', 'AES Corporation'), ('cnName', 'United States of America'), ('cName1', 'Shulbinsk Hydroelectric Power Plant'), ('cnName1', 'Soviet Union')]
# [('cName', 'AES Corporation'), ('cnName', 'United States of America'), ('cName1', 'AES Andes'), ('cnName1', 'Chile')]
# [('cName', 'AES Corporation'), ('cnName', 'United States of America'), ('cName1', 'Shulbinsk Hydroelectric Power Plant'), ('cnName1', 'Kazakhstan')]
# [('cName', 'AGCO'), ('cnName', 'United States of America'), ('cName1', 'Fendt'), ('cnName1', 'Germany')]
# [('cName', 'AGCO'), ('cnName', 'United States of America'), ('cName1', 'Fella-Werke'), ('cnName1', 'Germany')]
# [('cName', 'AGCO'), ('cnName', 'United States of America'), ('cName1', 'Laverda'), ('cnName1', 'Italy')]
# [('cName', 'AOL'), ('cnName', 'United States of America'), ('cName1', 'Mirabilis'), ('cnName1', 'Israel')]
# [('cName', 'Aberdeen Asset Management'), ('cnName', 'United Kingdom'), ('cName1', 'Yum China'), ('cnName1', "People's Republic of China")]
# [('cName', 'Aberdeen Asset Management'), ('cnName', 'United Kingdom'), ('cName1', 'Yum China'), ('cnName1', 'United States of America')]
# [('cName', 'Acclaim Entertainment'), ('cnName', 'United States of America'), ('cName1', 'Software Creations'), ('cnName1', 'United Kingdom')]
# [('cName', 'Acclaim Entertainment'), ('cnName', 'United States of America'), ('cName1', 'Acclaim Studios London'), ('cnName1', 'United Kingdom')]
# [('cName', 'Acclaim Entertainment'), ('cnName', 'United States of America'), ('cName1', 'Acclaim Studios Cheltenham'), ('cnName1', 'United Kingdom')]
# [('cName', 'Adobe'), ('cnName', 'United States of America'), ('cName1', 'Day Software'), ('cnName1', 'Switzerland')]
# [('cName', 'Advanced Micro Devices'), ('cnName', 'United States of America'), ('cName1', 'ATI Technologies'), ('cnName1', 'Canada')]
# [('cName', 'Agnico-Eagle Mines'), ('cnName', 'Canada'), ('cName1', 'Kittilä mine'), ('cnName1', 'Finland')]
# [('cName', 'Amazon'), ('cnName', 'United States of America'), ('cName1', 'LoveFilm'), ('cnName1', 'Germany')]
# [('cName', 'Amazon'), ('cnName', 'United States of America'), ('cName1', 'Book Depository'), ('cnName1', 'United Kingdom')]
# [('cName', 'Amazon'), ('cnName', 'United States of America'), ('cName1', 'AbeBooks'), ('cnName1', 'Germany')]
# [('cName', 'Amdocs'), ('cnName', 'United States of America'), ('cName1', 'FilmFlex'), ('cnName1', 'United Kingdom')]
# [('cName', 'Amdocs'), ('cnName', 'United States of America'), ('cName1', 'Cramer Systems'), ('cnName1', 'United Kingdom')]
# [('cName', 'American International Group'), ('cnName', 'United States of America'), ('cName1', 'AIA Central'), ('cnName1', "People's Republic of China")]
# [('cName', 'Anglo American plc'), ('cnName', 'United Kingdom'), ('cName1', 'De Beers'), ('cnName1', 'South Africa')]
# [('cName', 'Anglo-French Banking Corporation, Ltd.'), ('cnName', 'United Kingdom'), ('cName1', 'Banque des Pays du Nord'), ('cnName1', 'France')]
# [('cName', 'Anschutz Entertainment Group'), ('cnName', 'United States of America'), ('cName1', 'Barclaycard Arena'), ('cnName1', 'Germany')]
# [('cName', 'Anschutz Entertainment Group'), ('cnName', 'United States of America'), ('cName1', 'Mercedes-Benz Arena Berlin'), ('cnName1', 'Germany')]
# [('cName', 'Apax Partners'), ('cnName', 'United Kingdom'), ('cName1', 'Cole Haan'), ('cnName1', 'United States of America')]
# [('cName', 'Apax Partners'), ('cnName', 'United Kingdom'), ('cName1', 'Orange Communications Switzerland'), ('cnName1', 'Switzerland')]
# [('cName', 'Apax Partners'), ('cnName', 'United Kingdom'), ('cName1', 'Maisons du Monde'), ('cnName1', 'France')]
# [('cName', 'Apax Partners'), ('cnName', 'United Kingdom'), ('cName1', 'Zap Price Comparison'), ('cnName1', 'Israel')]
# [('cName', 'Apax Partners'), ('cnName', 'United Kingdom'), ('cName1', 'Business integration partners'), ('cnName1', 'Italy')]
# [('cName', 'Apollinaris and Presta'), ('cnName', 'United Kingdom'), ('cName1', 'Apollinaris'), ('cnName1', 'Germany')]
# [('cName', 'Apollo Group'), ('cnName', 'United States of America'), ('cName1', 'BPP Holdings'), ('cnName1', 'United Kingdom')]
# [('cName', 'Apple Inc.'), ('cnName', 'United States of America'), ('cName1', 'Imagination Technologies'), ('cnName1', 'United Kingdom')]
# [('cName', 'Arriva'), ('cnName', 'United Kingdom'), ('cName1', 'SAB Autoservizi'), ('cnName1', 'Italy')]
# [('cName', 'Arriva'), ('cnName', 'United Kingdom'), ('cName1', 'Società Italiana Autoservizi'), ('cnName1', 'Italy')]
# [('cName', 'Arriva'), ('cnName', 'United Kingdom'), ('cName1', 'ArrivaBus'), ('cnName1', 'Hungary')]
# [('cName', 'Arriva'), ('cnName', 'United Kingdom'), ('cName1', 'SAL Lecco'), ('cnName1', 'Italy')]
# [('cName', 'Arriva International Limited'), ('cnName', 'United Kingdom'), ('cName1', 'Arriva Transport Česká republika'), ('cnName1', 'Czech Republic')]
# [('cName', 'Asahi Breweries Europe'), ('cnName', 'United Kingdom'), ('cName1', 'Plzeňský Prazdroj'), ('cnName1', 'Czech Republic')]
# [('cName', 'Asahi Breweries Europe'), ('cnName', 'United Kingdom'), ('cName1', 'Dreher Breweries'), ('cnName1', 'Hungary')]
# [('cName', 'Asahi Breweries Europe'), ('cnName', 'United Kingdom'), ('cName1', 'Asahi Brands Germany'), ('cnName1', 'Germany')]
# [('cName', 'Asahi Breweries Europe'), ('cnName', 'United Kingdom'), ('cName1', 'Ursus Breweries'), ('cnName1', 'Romania')]
# [('cName', 'Associated British Foods'), ('cnName', 'United Kingdom'), ('cName1', 'Primark'), ('cnName1', 'Ireland')]
# [('cName', 'Associated British Foods'), ('cnName', 'United Kingdom'), ('cName1', 'George Weston Foods'), ('cnName1', 'Australia')]
# [('cName', 'AstraZeneca'), ('cnName', 'United Kingdom'), ('cName1', 'Moderna'), ('cnName1', 'United States of America')]
# [('cName', 'AstraZeneca'), ('cnName', 'United Kingdom'), ('cName1', 'PhaseBio Pharmaceuticals (United States)'), ('cnName1', 'United States of America')]
# [('cName', 'AstraZeneca'), ('cnName', 'United Kingdom'), ('cName1', 'ADC Therapeutics'), ('cnName1', 'Switzerland')]
# [('cName', 'AstraZeneca'), ('cnName', 'United Kingdom'), ('cName1', 'Montrose Chemical Corporation of California'), ('cnName1', 'United States of America')]
# [('cName', 'AstraZeneca'), ('cnName', 'United Kingdom'), ('cName1', 'Entasis Therapeutics'), ('cnName1', 'United States of America')]
# [('cName', 'Australian Estates Company'), ('cnName', 'United Kingdom'), ('cName1', 'Elderslie Station'), ('cnName1', 'Australia')]
# [('cName', 'Aviva'), ('cnName', 'United Kingdom'), ('cName1', 'DeltaFort Beleggingen I'), ('cnName1', 'Netherlands')]
# [('cName', 'Aviva'), ('cnName', 'United Kingdom'), ('cName1', 'Tour Carpe Diem'), ('cnName1', 'France')]
# [('cName', 'BBC'), ('cnName', 'United Kingdom'), ('cName1', 'BBC Persian Television'), ('cnName1', 'Afghanistan')]
# [('cName', 'BBC'), ('cnName', 'United Kingdom'), ('cName1', 'BBC Persian Television'), ('cnName1', 'Iran')]
# [('cName', 'BBC'), ('cnName', 'United Kingdom'), ('cName1', 'BBC World News'), ('cnName1', 'Russia')]
# [('cName', 'BBC'), ('cnName', 'United Kingdom'), ('cName1', 'BBC South Asia'), ('cnName1', 'India')]
# [('cName', 'BBC'), ('cnName', 'United Kingdom'), ('cName1', 'BBC Persian Television'), ('cnName1', 'Tajikistan')]
# [('cName', 'Bain Capital'), ('cnName', 'United States of America'), ('cName1', 'Ideal Standard International'), ('cnName1', 'Belgium')]
# [('cName', 'Bank of America'), ('cnName', 'United States of America'), ('cName1', 'Second Severn Crossing'), ('cnName1', 'United Kingdom')]
# [('cName', 'Barclays'), ('cnName', 'United Kingdom'), ('cName1', 'ABSA Group Limited'), ('cnName1', 'South Africa')]
# [('cName', 'Barrick Gold'), ('cnName', 'Canada'), ('cName1', 'Kirondatal Gold Mine'), ('cnName1', 'Tanzania')]
# [('cName', 'Barrick Gold'), ('cnName', 'Canada'), ('cName1', 'Cortez Gold Mine'), ('cnName1', 'United States of America')]
# [('cName', 'Barrick Gold'), ('cnName', 'Canada'), ('cName1', 'Darlot-Centenary Gold Mine'), ('cnName1', 'Australia')]
# 70

# %% [markdown]
# I want some numerical values. Owned companies outside their countries

# %%
queryString = """
SELECT DISTINCT ?company ?cName ?cnName COUNT(DISTINCT(?cName1)) AS ?numOfForeignComp
WHERE {

# ?company wdt:P17 ?country .
# ?company wdt:P31 wd:Q4830453  . 

# ?company wdt:P1830 ?obj5 . #owner of
# ?obj5 wdt:P17 ?country1.

# ?obj5 <http://schema.org/name> ?cName1 .
# ?company <http://schema.org/name> ?cName .
# ?country <http://schema.org/name> ?cnName .
# ?country1 <http://schema.org/name> ?cnName1 .

FILTER (?country1 != ?country)
FILTER (?country = wd:Q30 || ?country = wd:Q145 || ?country = wd:Q16)
} 
GROUP BY (?cName) (?cnName) (?company)
ORDER BY ASC(?cnName)

"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('company', 'http://www.wikidata.org/entity/Q835702'), ('cName', 'Corel'), ('cnName', 'Canada'), ('numOfForeignComp', '3')]
# [('company', 'http://www.wikidata.org/entity/Q303439'), ('cName', 'Legoland Discovery Centre'), ('cnName', 'Canada'), ('numOfForeignComp', '1')]
# [('company', 'http://www.wikidata.org/entity/Q83420552'), ('cName', 'Iskut IMC'), ('cnName', 'Canada'), ('numOfForeignComp', '1')]
# [('company', 'http://www.wikidata.org/entity/Q76039'), ('cName', "Hudson's Bay Company"), ('cnName', 'Canada'), ('numOfForeignComp', '2')]
# [('company', 'http://www.wikidata.org/entity/Q808908'), ('cName', 'Barrick Gold'), ('cnName', 'Canada'), ('numOfForeignComp', '5')]
# [('company', 'http://www.wikidata.org/entity/Q7318069'), ('cName', 'Revera'), ('cnName', 'Canada'), ('numOfForeignComp', '1')]
# [('company', 'http://www.wikidata.org/entity/Q1412968'), ('cName', 'NRJ Group'), ('cnName', 'Canada'), ('numOfForeignComp', '1')]
# [('company', 'http://www.wikidata.org/entity/Q61862560'), ('cName', 'Borealis International Investments Corporation'), ('cnName', 'Canada'), ('numOfForeignComp', '1')]
# [('company', 'http://www.wikidata.org/entity/Q38676'), ('cName', 'Agnico-Eagle Mines'), ('cnName', 'Canada'), ('numOfForeignComp', '1')]
# [('company', 'http://www.wikidata.org/entity/Q571779'), ('cName', 'Liberty Global'), ('cnName', 'United Kingdom'), ('numOfForeignComp', '8')]
# [('company', 'http://www.wikidata.org/entity/Q117059'), ('cName', 'Associated British Foods'), ('cnName', 'United Kingdom'), ('numOfForeignComp', '2')]
# [('company', 'http://www.wikidata.org/entity/Q19608057'), ('cName', 'Brazilian Warrant Agency and Finance Co'), ('cnName', 'United Kingdom'), ('numOfForeignComp', '1')]
# [('company', 'http://www.wikidata.org/entity/Q43930212'), ('cName', 'Macquarie Infrastructure and Real Assets (Europe) Limited'), ('cnName', 'United Kingdom'), ('numOfForeignComp', '1')]
# [('company', 'http://www.wikidata.org/entity/Q685018'), ('cName', 'Future plc'), ('cnName', 'United Kingdom'), ('numOfForeignComp', '2')]
# [('company', 'http://www.wikidata.org/entity/Q51838892'), ('cName', 'Tesco Overseas Investments Limited'), ('cnName', 'United Kingdom'), ('numOfForeignComp', '1')]
# [('company', 'http://www.wikidata.org/entity/Q154950'), ('cName', 'Royal Dutch Shell'), ('cnName', 'United Kingdom'), ('numOfForeignComp', '4')]
# [('company', 'http://www.wikidata.org/entity/Q76658524'), ('cName', 'Rossum'), ('cnName', 'United Kingdom'), ('numOfForeignComp', '1')]
# [('company', 'http://www.wikidata.org/entity/Q791179'), ('cName', 'Aviva'), ('cnName', 'United Kingdom'), ('numOfForeignComp', '2')]
# [('company', 'http://www.wikidata.org/entity/Q64870882'), ('cName', 'Vesuvius Overseas Limited'), ('cnName', 'United Kingdom'), ('numOfForeignComp', '1')]
# [('company', 'http://www.wikidata.org/entity/Q541451'), ('cName', 'Anglo American plc'), ('cnName', 'United Kingdom'), ('numOfForeignComp', '1')]
# [('company', 'http://www.wikidata.org/entity/Q161140'), ('cName', 'Diageo'), ('cnName', 'United Kingdom'), ('numOfForeignComp', '5')]
# [('company', 'http://www.wikidata.org/entity/Q9531'), ('cName', 'BBC'), ('cnName', 'United Kingdom'), ('numOfForeignComp', '3')]
# [('company', 'http://www.wikidata.org/entity/Q29613327'), ('cName', 'Asahi Breweries Europe'), ('cnName', 'United Kingdom'), ('numOfForeignComp', '4')]
# [('company', 'http://www.wikidata.org/entity/Q60605637'), ('cName', 'IRG Steel Limited'), ('cnName', 'United Kingdom'), ('numOfForeignComp', '1')]
# [('company', 'http://www.wikidata.org/entity/Q102280007'), ('cName', 'Dorada Railway Company, Ltd.'), ('cnName', 'United Kingdom'), ('numOfForeignComp', '1')]
# [('company', 'http://www.wikidata.org/entity/Q731938'), ('cName', 'AstraZeneca'), ('cnName', 'United Kingdom'), ('numOfForeignComp', '5')]
# [('company', 'http://www.wikidata.org/entity/Q98959120'), ('cName', 'Arriva International Limited'), ('cnName', 'United Kingdom'), ('numOfForeignComp', '1')]
# [('company', 'http://www.wikidata.org/entity/Q303439'), ('cName', 'Legoland Discovery Centre'), ('cnName', 'United Kingdom'), ('numOfForeignComp', '2')]
# [('company', 'http://www.wikidata.org/entity/Q29110228'), ('cName', 'Panasonic Europe Ltd'), ('cnName', 'United Kingdom'), ('numOfForeignComp', '2')]
# [('company', 'http://www.wikidata.org/entity/Q245343'), ('cName', 'Barclays'), ('cnName', 'United Kingdom'), ('numOfForeignComp', '1')]
# [('company', 'http://www.wikidata.org/entity/Q4995'), ('cName', 'SABMiller'), ('cnName', 'United Kingdom'), ('numOfForeignComp', '8')]
# [('company', 'http://www.wikidata.org/entity/Q122141'), ('cName', 'Vodafone'), ('cnName', 'United Kingdom'), ('numOfForeignComp', '7')]
# [('company', 'http://www.wikidata.org/entity/Q474153'), ('cName', 'Economist Group'), ('cnName', 'United Kingdom'), ('numOfForeignComp', '1')]
# [('company', 'http://www.wikidata.org/entity/Q104175647'), ('cName', 'Guillemot Brothers'), ('cnName', 'United Kingdom'), ('numOfForeignComp', '1')]
# [('company', 'http://www.wikidata.org/entity/Q289704'), ('cName', 'Old Mutual'), ('cnName', 'United Kingdom'), ('numOfForeignComp', '1')]
# [('company', 'http://www.wikidata.org/entity/Q618098'), ('cName', 'Apax Partners'), ('cnName', 'United Kingdom'), ('numOfForeignComp', '5')]
# [('company', 'http://www.wikidata.org/entity/Q69503098'), ('cName', 'Startup Yard'), ('cnName', 'United Kingdom'), ('numOfForeignComp', '3')]
# [('company', 'http://www.wikidata.org/entity/Q487494'), ('cName', 'Tesco'), ('cnName', 'United Kingdom'), ('numOfForeignComp', '2')]
# [('company', 'http://www.wikidata.org/entity/Q694872'), ('cName', 'TORM'), ('cnName', 'United Kingdom'), ('numOfForeignComp', '1')]
# [('company', 'http://www.wikidata.org/entity/Q782697'), ('cName', 'Compass Group'), ('cnName', 'United Kingdom'), ('numOfForeignComp', '2')]
# [('company', 'http://www.wikidata.org/entity/Q481356'), ('cName', 'IG Group'), ('cnName', 'United Kingdom'), ('numOfForeignComp', '1')]
# [('company', 'http://www.wikidata.org/entity/Q821293'), ('cName', 'Rio Tinto Group'), ('cnName', 'United Kingdom'), ('numOfForeignComp', '5')]
# [('company', 'http://www.wikidata.org/entity/Q85622509'), ('cName', 'Rolls-Royce Group'), ('cnName', 'United Kingdom'), ('numOfForeignComp', '1')]
# [('company', 'http://www.wikidata.org/entity/Q502316'), ('cName', 'Hammerson'), ('cnName', 'United Kingdom'), ('numOfForeignComp', '4')]
# [('company', 'http://www.wikidata.org/entity/Q708240'), ('cName', 'Corus'), ('cnName', 'United Kingdom'), ('numOfForeignComp', '2')]
# [('company', 'http://www.wikidata.org/entity/Q319468'), ('cName', 'Aberdeen Asset Management'), ('cnName', 'United Kingdom'), ('numOfForeignComp', '1')]
# [('company', 'http://www.wikidata.org/entity/Q673231'), ('cName', 'INEOS'), ('cnName', 'United Kingdom'), ('numOfForeignComp', '1')]
# [('company', 'http://www.wikidata.org/entity/Q680991'), ('cName', 'Arriva'), ('cnName', 'United Kingdom'), ('numOfForeignComp', '4')]
# [('company', 'http://www.wikidata.org/entity/Q190464'), ('cName', 'HSBC'), ('cnName', 'United Kingdom'), ('numOfForeignComp', '1')]
# [('company', 'http://www.wikidata.org/entity/Q83780068'), ('cName', 'Geneva BrassWind'), ('cnName', 'United Kingdom'), ('numOfForeignComp', '1')]
# [('company', 'http://www.wikidata.org/entity/Q1412968'), ('cName', 'NRJ Group'), ('cnName', 'United Kingdom'), ('numOfForeignComp', '1')]
# [('company', 'http://www.wikidata.org/entity/Q104382018'), ('cName', 'Apollinaris and Presta'), ('cnName', 'United Kingdom'), ('numOfForeignComp', '1')]
# [('company', 'http://www.wikidata.org/entity/Q662030'), ('cName', 'Permira'), ('cnName', 'United Kingdom'), ('numOfForeignComp', '1')]
# [('company', 'http://www.wikidata.org/entity/Q8774'), ('cName', 'International Airlines Group'), ('cnName', 'United Kingdom'), ('numOfForeignComp', '3')]
# [('company', 'http://www.wikidata.org/entity/Q683098'), ('cName', 'Kingfisher plc'), ('cnName', 'United Kingdom'), ('numOfForeignComp', '1')]
# [('company', 'http://www.wikidata.org/entity/Q29785200'), ('cName', 'Parvus Asset Management Europe Limited'), ('cnName', 'United Kingdom'), ('numOfForeignComp', '1')]
# [('company', 'http://www.wikidata.org/entity/Q183412'), ('cName', 'EMI'), ('cnName', 'United Kingdom'), ('numOfForeignComp', '6')]
# [('company', 'http://www.wikidata.org/entity/Q1119662'), ('cName', 'Imagination Technologies'), ('cnName', 'United Kingdom'), ('numOfForeignComp', '1')]
# [('company', 'http://www.wikidata.org/entity/Q679933'), ('cName', 'Eidos Interactive'), ('cnName', 'United Kingdom'), ('numOfForeignComp', '2')]
# [('company', 'http://www.wikidata.org/entity/Q103935826'), ('cName', 'Australian Estates Company'), ('cnName', 'United Kingdom'), ('numOfForeignComp', '1')]
# [('company', 'http://www.wikidata.org/entity/Q6084088'), ('cName', 'Isle of Wight Central Railway'), ('cnName', 'United Kingdom'), ('numOfForeignComp', '8')]
# [('company', 'http://www.wikidata.org/entity/Q104812849'), ('cName', 'Anglo-French Banking Corporation, Ltd.'), ('cnName', 'United Kingdom'), ('numOfForeignComp', '1')]
# [('company', 'http://www.wikidata.org/entity/Q81334023'), ('cName', 'CBC Global Ammunition'), ('cnName', 'United States of America'), ('numOfForeignComp', '1')]
# [('company', 'http://www.wikidata.org/entity/Q37093'), ('cName', 'Yahoo'), ('cnName', 'United States of America'), ('numOfForeignComp', '2')]
# [('company', 'http://www.wikidata.org/entity/Q1324524'), ('cName', 'Fenway Sports Group'), ('cnName', 'United States of America'), ('numOfForeignComp', '2')]
# [('company', 'http://www.wikidata.org/entity/Q214346'), ('cName', 'Viacom'), ('cnName', 'United States of America'), ('numOfForeignComp', '20')]
# [('company', 'http://www.wikidata.org/entity/Q27585'), ('cName', 'AOL'), ('cnName', 'United States of America'), ('numOfForeignComp', '1')]
# [('company', 'http://www.wikidata.org/entity/Q29641366'), ('cName', 'FMR Co.'), ('cnName', 'United States of America'), ('numOfForeignComp', '1')]
# [('company', 'http://www.wikidata.org/entity/Q72539'), ('cName', 'U.S. Steel'), ('cnName', 'United States of America'), ('numOfForeignComp', '1')]
# [('company', 'http://www.wikidata.org/entity/Q2283'), ('cName', 'Microsoft'), ('cnName', 'United States of America'), ('numOfForeignComp', '9')]
# [('company', 'http://www.wikidata.org/entity/Q38076'), ('cName', 'McDonald’s'), ('cnName', 'United States of America'), ('numOfForeignComp', '2')]
# [('company', 'http://www.wikidata.org/entity/Q83723'), ('cName', 'A&E Networks'), ('cnName', 'United States of America'), ('numOfForeignComp', '4')]
# [('company', 'http://www.wikidata.org/entity/Q13977'), ('cName', 'Bloomberg L.P.'), ('cnName', 'United States of America'), ('numOfForeignComp', '2')]
# [('company', 'http://www.wikidata.org/entity/Q522617'), ('cName', 'Invesco'), ('cnName', 'United States of America'), ('numOfForeignComp', '3')]
# [('company', 'http://www.wikidata.org/entity/Q634831'), ('cName', 'Sheraton Hotels and Resorts'), ('cnName', 'United States of America'), ('numOfForeignComp', '3')]
# [('company', 'http://www.wikidata.org/entity/Q60687118'), ('cName', 'GE Money Czech Holding Company'), ('cnName', 'United States of America'), ('numOfForeignComp', '1')]
# [('company', 'http://www.wikidata.org/entity/Q744683'), ('cName', 'Franklin Templeton Investments'), ('cnName', 'United States of America'), ('numOfForeignComp', '3')]
# [('company', 'http://www.wikidata.org/entity/Q19724671'), ('cName', 'Radisson Hotel Group'), ('cnName', 'United States of America'), ('numOfForeignComp', '2')]
# [('company', 'http://www.wikidata.org/entity/Q634815'), ('cName', 'Motorola Solutions'), ('cnName', 'United States of America'), ('numOfForeignComp', '1')]
# [('company', 'http://www.wikidata.org/entity/Q95148451'), ('cName', 'Home Box Office, Inc.'), ('cnName', 'United States of America'), ('numOfForeignComp', '1')]
# [('company', 'http://www.wikidata.org/entity/Q152433'), ('cName', 'Xerox'), ('cnName', 'United States of America'), ('numOfForeignComp', '1')]
# [('company', 'http://www.wikidata.org/entity/Q214763'), ('cName', 'ConocoPhillips'), ('cnName', 'United States of America'), ('numOfForeignComp', '1')]
# [('company', 'http://www.wikidata.org/entity/Q667599'), ('cName', 'Newell Brands'), ('cnName', 'United States of America'), ('numOfForeignComp', '1')]
# [('company', 'http://www.wikidata.org/entity/Q44294'), ('cName', 'Ford Motor Company'), ('cnName', 'United States of America'), ('numOfForeignComp', '12')]
# [('company', 'http://www.wikidata.org/entity/Q857063'), ('cName', 'Citibank'), ('cnName', 'United States of America'), ('numOfForeignComp', '3')]
# [('company', 'http://www.wikidata.org/entity/Q2031485'), ('cName', 'Under Armour'), ('cnName', 'United States of America'), ('numOfForeignComp', '1')]
# [('company', 'http://www.wikidata.org/entity/Q1197548'), ('cName', 'Micron Technology'), ('cnName', 'United States of America'), ('numOfForeignComp', '1')]
# [('company', 'http://www.wikidata.org/entity/Q460446'), ('cName', 'Amdocs'), ('cnName', 'United States of America'), ('numOfForeignComp', '2')]
# [('company', 'http://www.wikidata.org/entity/Q156238'), ('cName', 'ExxonMobil'), ('cnName', 'United States of America'), ('numOfForeignComp', '3')]
# [('company', 'http://www.wikidata.org/entity/Q637440'), ('cName', 'Lazard'), ('cnName', 'United States of America'), ('numOfForeignComp', '2')]
# [('company', 'http://www.wikidata.org/entity/Q706094'), ('cName', 'Stanley Black & Decker'), ('cnName', 'United States of America'), ('numOfForeignComp', '1')]
# [('company', 'http://www.wikidata.org/entity/Q292292'), ('cName', 'AGCO'), ('cnName', 'United States of America'), ('numOfForeignComp', '3')]
# [('company', 'http://www.wikidata.org/entity/Q787239'), ('cName', 'Platinum Equity'), ('cnName', 'United States of America'), ('numOfForeignComp', '1')]
# [('company', 'http://www.wikidata.org/entity/Q334204'), ('cName', 'Morgan Stanley'), ('cnName', 'United States of America'), ('numOfForeignComp', '3')]
# [('company', 'http://www.wikidata.org/entity/Q76846862'), ('cName', 'ViacomCBS'), ('cnName', 'United States of America'), ('numOfForeignComp', '1')]
# [('company', 'http://www.wikidata.org/entity/Q219508'), ('cName', 'Citigroup'), ('cnName', 'United States of America'), ('numOfForeignComp', '2')]
# [('company', 'http://www.wikidata.org/entity/Q173150'), ('cName', 'Pratt & Whitney'), ('cnName', 'United States of America'), ('numOfForeignComp', '1')]
# [('company', 'http://www.wikidata.org/entity/Q620875'), ('cName', 'Goodyear Tire and Rubber Company'), ('cnName', 'United States of America'), ('numOfForeignComp', '1')]
# [('company', 'http://www.wikidata.org/entity/Q291508'), ('cName', 'AES Corporation'), ('cnName', 'United States of America'), ('numOfForeignComp', '2')]
# [('company', 'http://www.wikidata.org/entity/Q457960'), ('cName', 'VF Corporation'), ('cnName', 'United States of America'), ('numOfForeignComp', '1')]
# [('company', 'http://www.wikidata.org/entity/Q1570773'), ('cName', 'Kohlberg Kravis Roberts'), ('cnName', 'United States of America'), ('numOfForeignComp', '2')]
# [('company', 'http://www.wikidata.org/entity/Q11463'), ('cName', 'Adobe'), ('cnName', 'United States of America'), ('numOfForeignComp', '1')]
# [('company', 'http://www.wikidata.org/entity/Q19884156'), ('cName', 'Tennant Company'), ('cnName', 'United States of America'), ('numOfForeignComp', '1')]
# [('company', 'http://www.wikidata.org/entity/Q392221'), ('cName', 'Brown-Forman'), ('cnName', 'United States of America'), ('numOfForeignComp', '1')]
# [('company', 'http://www.wikidata.org/entity/Q658789'), ('cName', 'Garmin'), ('cnName', 'United States of America'), ('numOfForeignComp', '1')]
# [('company', 'http://www.wikidata.org/entity/Q85817428'), ('cName', 'Productboard'), ('cnName', 'United States of America'), ('numOfForeignComp', '1')]
# [('company', 'http://www.wikidata.org/entity/Q609766'), ('cName', '3G Capital'), ('cnName', 'United States of America'), ('numOfForeignComp', '3')]
# [('company', 'http://www.wikidata.org/entity/Q289362'), ('cName', 'Cerberus Capital Management'), ('cnName', 'United States of America'), ('numOfForeignComp', '2')]
# [('company', 'http://www.wikidata.org/entity/Q3884'), ('cName', 'Amazon'), ('cnName', 'United States of America'), ('numOfForeignComp', '3')]
# [('company', 'http://www.wikidata.org/entity/Q128896'), ('cName', 'Advanced Micro Devices'), ('cnName', 'United States of America'), ('numOfForeignComp', '1')]
# [('company', 'http://www.wikidata.org/entity/Q181114'), ('cName', 'Chrysler'), ('cnName', 'United States of America'), ('numOfForeignComp', '2')]
# [('company', 'http://www.wikidata.org/entity/Q210278'), ('cName', 'Gibson'), ('cnName', 'United States of America'), ('numOfForeignComp', '1')]
# [('company', 'http://www.wikidata.org/entity/Q740999'), ('cName', 'TIAA'), ('cnName', 'United States of America'), ('numOfForeignComp', '1')]
# [('company', 'http://www.wikidata.org/entity/Q459965'), ('cName', 'Caterpillar Inc.'), ('cnName', 'United States of America'), ('numOfForeignComp', '1')]
# [('company', 'http://www.wikidata.org/entity/Q632240'), ('cName', 'Eli Lilly and Company'), ('cnName', 'United States of America'), ('numOfForeignComp', '1')]
# [('company', 'http://www.wikidata.org/entity/Q503592'), ('cName', 'Gillette'), ('cnName', 'United States of America'), ('numOfForeignComp', '1')]
# [('company', 'http://www.wikidata.org/entity/Q212235'), ('cName', 'American International Group'), ('cnName', 'United States of America'), ('numOfForeignComp', '1')]
# [('company', 'http://www.wikidata.org/entity/Q803873'), ('cName', 'Bain Capital'), ('cnName', 'United States of America'), ('numOfForeignComp', '1')]
# [('company', 'http://www.wikidata.org/entity/Q312'), ('cName', 'Apple Inc.'), ('cnName', 'United States of America'), ('numOfForeignComp', '1')]
# [('company', 'http://www.wikidata.org/entity/Q58024'), ('cName', 'eBay'), ('cnName', 'United States of America'), ('numOfForeignComp', '1')]
# [('company', 'http://www.wikidata.org/entity/Q569417'), ('cName', 'Anschutz Entertainment Group'), ('cnName', 'United States of America'), ('numOfForeignComp', '2')]
# [('company', 'http://www.wikidata.org/entity/Q466183'), ('cName', 'Reebok'), ('cnName', 'United States of America'), ('numOfForeignComp', '1')]
# [('company', 'http://www.wikidata.org/entity/Q689475'), ('cName', 'Laureate Education'), ('cnName', 'United States of America'), ('numOfForeignComp', '2')]
# [('company', 'http://www.wikidata.org/entity/Q305249'), ('cName', 'Haworth'), ('cnName', 'United States of America'), ('numOfForeignComp', '1')]
# [('company', 'http://www.wikidata.org/entity/Q3544836'), ('cName', 'Radio Mindanao Network'), ('cnName', 'United States of America'), ('numOfForeignComp', '2')]
# [('company', 'http://www.wikidata.org/entity/Q192314'), ('cName', 'JPMorgan Chase'), ('cnName', 'United States of America'), ('numOfForeignComp', '2')]
# [('company', 'http://www.wikidata.org/entity/Q334122'), ('cName', 'Merrill Lynch'), ('cnName', 'United States of America'), ('numOfForeignComp', '1')]
# [('company', 'http://www.wikidata.org/entity/Q66'), ('cName', 'Boeing'), ('cnName', 'United States of America'), ('numOfForeignComp', '1')]
# [('company', 'http://www.wikidata.org/entity/Q95'), ('cName', 'Google'), ('cnName', 'United States of America'), ('numOfForeignComp', '7')]
# [('company', 'http://www.wikidata.org/entity/Q785943'), ('cName', 'Staples Inc.'), ('cnName', 'United States of America'), ('numOfForeignComp', '1')]
# [('company', 'http://www.wikidata.org/entity/Q683170'), ('cName', 'S. C. Johnson & Son'), ('cnName', 'United States of America'), ('numOfForeignComp', '2')]
# [('company', 'http://www.wikidata.org/entity/Q459477'), ('cName', 'FedEx'), ('cnName', 'United States of America'), ('numOfForeignComp', '1')]
# [('company', 'http://www.wikidata.org/entity/Q477178'), ('cName', 'Sun Capital Partners'), ('cnName', 'United States of America'), ('numOfForeignComp', '1')]
# [('company', 'http://www.wikidata.org/entity/Q27022329'), ('cName', 'Snap Inc.'), ('cnName', 'United States of America'), ('numOfForeignComp', '1')]
# [('company', 'http://www.wikidata.org/entity/Q191715'), ('cName', 'WarnerMedia'), ('cnName', 'United States of America'), ('numOfForeignComp', '22')]
# [('company', 'http://www.wikidata.org/entity/Q619111'), ('cName', 'Apollo Group'), ('cnName', 'United States of America'), ('numOfForeignComp', '1')]
# [('company', 'http://www.wikidata.org/entity/Q333718'), ('cName', 'Johnson & Johnson'), ('cnName', 'United States of America'), ('numOfForeignComp', '4')]
# [('company', 'http://www.wikidata.org/entity/Q741707'), ('cName', 'Wabtec'), ('cnName', 'United States of America'), ('numOfForeignComp', '1')]
# [('company', 'http://www.wikidata.org/entity/Q339228'), ('cName', 'Acclaim Entertainment'), ('cnName', 'United States of America'), ('numOfForeignComp', '3')]
# [('company', 'http://www.wikidata.org/entity/Q440774'), ('cName', 'QVC'), ('cnName', 'United States of America'), ('numOfForeignComp', '1')]
# [('company', 'http://www.wikidata.org/entity/Q185278'), ('cName', 'News Corporation'), ('cnName', 'United States of America'), ('numOfForeignComp', '10')]
# [('company', 'http://www.wikidata.org/entity/Q54173'), ('cName', 'General Electric'), ('cnName', 'United States of America'), ('numOfForeignComp', '6')]
# [('company', 'http://www.wikidata.org/entity/Q533415'), ('cName', 'Best Buy'), ('cnName', 'United States of America'), ('numOfForeignComp', '1')]
# [('company', 'http://www.wikidata.org/entity/Q48881'), ('cName', 'Sherwin-Williams'), ('cnName', 'United States of America'), ('numOfForeignComp', '1')]
# [('company', 'http://www.wikidata.org/entity/Q212405'), ('cName', 'Procter & Gamble'), ('cnName', 'United States of America'), ('numOfForeignComp', '2')]
# [('company', 'http://www.wikidata.org/entity/Q926806'), ('cName', 'Carlyle Group'), ('cnName', 'United States of America'), ('numOfForeignComp', '1')]
# [('company', 'http://www.wikidata.org/entity/Q552363'), ('cName', 'Starwood Hotels and Resorts Worldwide'), ('cnName', 'United States of America'), ('numOfForeignComp', '7')]
# [('company', 'http://www.wikidata.org/entity/Q303439'), ('cName', 'Legoland Discovery Centre'), ('cnName', 'United States of America'), ('numOfForeignComp', '2')]
# [('company', 'http://www.wikidata.org/entity/Q609466'), ('cName', 'Colgate-Palmolive Company'), ('cnName', 'United States of America'), ('numOfForeignComp', '3')]
# [('company', 'http://www.wikidata.org/entity/Q35339'), ('cName', 'WWE'), ('cnName', 'United States of America'), ('numOfForeignComp', '1')]
# [('company', 'http://www.wikidata.org/entity/Q5570413'), ('cName', 'Global Infrastructure Partners'), ('cnName', 'United States of America'), ('numOfForeignComp', '5')]
# [('company', 'http://www.wikidata.org/entity/Q671421'), ('cName', 'Institute for Scientific Information'), ('cnName', 'United States of America'), ('numOfForeignComp', '1')]
# [('company', 'http://www.wikidata.org/entity/Q126399'), ('cName', 'Warner Bros.'), ('cnName', 'United States of America'), ('numOfForeignComp', '2')]
# [('company', 'http://www.wikidata.org/entity/Q7414'), ('cName', 'The Walt Disney Company'), ('cnName', 'United States of America'), ('numOfForeignComp', '59')]
# [('company', 'http://www.wikidata.org/entity/Q555925'), ('cName', 'Broadcom'), ('cnName', 'United States of America'), ('numOfForeignComp', '1')]
# [('company', 'http://www.wikidata.org/entity/Q98081129'), ('cName', 'Twitch Interactive'), ('cnName', 'United States of America'), ('numOfForeignComp', '1')]
# [('company', 'http://www.wikidata.org/entity/Q483551'), ('cName', 'Walmart'), ('cnName', 'United States of America'), ('numOfForeignComp', '5')]
# [('company', 'http://www.wikidata.org/entity/Q621592'), ('cName', 'Discovery Inc.'), ('cnName', 'United States of America'), ('numOfForeignComp', '17')]
# [('company', 'http://www.wikidata.org/entity/Q487907'), ('cName', 'Bank of America'), ('cnName', 'United States of America'), ('numOfForeignComp', '1')]
# [('company', 'http://www.wikidata.org/entity/Q596139'), ('cName', 'Mattel'), ('cnName', 'United States of America'), ('numOfForeignComp', '2')]
# [('company', 'http://www.wikidata.org/entity/Q219635'), ('cName', 'BlackRock'), ('cnName', 'United States of America'), ('numOfForeignComp', '5')]
# [('company', 'http://www.wikidata.org/entity/Q37156'), ('cName', 'IBM'), ('cnName', 'United States of America'), ('numOfForeignComp', '2')]
# [('company', 'http://www.wikidata.org/entity/Q1520122'), ('cName', 'Getty Images'), ('cnName', 'United States of America'), ('numOfForeignComp', '1')]
# [('company', 'http://www.wikidata.org/entity/Q839466'), ('cName', "Domino's Pizza"), ('cnName', 'United States of America'), ('numOfForeignComp', '1')]
# [('company', 'http://www.wikidata.org/entity/Q420837'), ('cName', 'Firestone Tire and Rubber Company'), ('cnName', 'United States of America'), ('numOfForeignComp', '1')]
# [('company', 'http://www.wikidata.org/entity/Q849363'), ('cName', 'The Vanguard Group'), ('cnName', 'United States of America'), ('numOfForeignComp', '3')]
# [('company', 'http://www.wikidata.org/entity/Q490543'), ('cName', 'Lone Star Funds'), ('cnName', 'United States of America'), ('numOfForeignComp', '2')]
# 167

# %%
Finally

# %%
queryString = """
SELECT DISTINCT ?cnName COUNT(DISTINCT(?company)) AS ?numCompany COUNT(DISTINCT(?cName1)) AS ?numOfForeignComp
WHERE {

# ?company wdt:P17 ?country .
# ?company wdt:P31 wd:Q4830453  . 

# ?company wdt:P1830 ?obj5 . #owner of
# ?obj5 wdt:P17 ?country1.

# ?obj5 <http://schema.org/name> ?cName1 .
# ?company <http://schema.org/name> ?cName .
# ?country <http://schema.org/name> ?cnName .
# ?country1 <http://schema.org/name> ?cnName1 .

FILTER (?country1 != ?country)
FILTER (?country = wd:Q30 || ?country = wd:Q145 || ?country = wd:Q16)
} 
GROUP BY (?cnName) 
ORDER BY ASC(?cnName)

"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('cnName', 'Canada'), ('numCompany', '9'), ('numOfForeignComp', '16')]
# [('cnName', 'United Kingdom'), ('numCompany', '53'), ('numOfForeignComp', '126')]
# [('cnName', 'United States of America'), ('numCompany', '105'), ('numOfForeignComp', '327')]
# 3

# %% [markdown]
# **Answer 3**
#
# As we can se from the previous queries in the considered countries(UK, Canada, USA) there are companies that own companies in other countries

# %% [markdown]
# -------------
# **4 - Companies have different 'legal forms', compare the number of companies divided in different legal forms**
#
# From the first query I can see that P1454 is "legal form"

# %%
queryString = """
SELECT DISTINCT ?cnName COUNT(DISTINCT(?lgName)) AS ?numLegalForms
WHERE {

# ?company wdt:P17 ?country .
# ?company wdt:P31 wd:Q4830453  . 
# ?company wdt:P1454 ?legalForm .

# ?company <http://schema.org/name> ?cName .
# ?country <http://schema.org/name> ?cnName .
# ?legalForm <http://schema.org/name> ?lgName .


FILTER (?country = wd:Q30 || ?country = wd:Q145 || ?country = wd:Q16)
} 
GROUP BY (?cnName)
ORDER BY ASC(?cnName)

"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('cnName', 'Canada'), ('numLegalForms', '30')]
# [('cnName', 'United Kingdom'), ('numLegalForms', '43')]
# [('cnName', 'United States of America'), ('numLegalForms', '84')]
# 3

# %% [markdown]
# Now I look for the number of companies in each different legal form. Exploring Canada because of the number of different legal forms

# %%
queryString = """
SELECT DISTINCT ?cnName ?lgName COUNT(DISTINCT(?company)) AS ?num
WHERE {

# ?company wdt:P17 ?country .
# ?company wdt:P31 wd:Q4830453  . 
# ?company wdt:P1454 ?legalForm .

# ?company <http://schema.org/name> ?cName .
# ?country <http://schema.org/name> ?cnName .
# ?legalForm <http://schema.org/name> ?lgName .


FILTER (?country = wd:Q16)
} 
GROUP BY (?cnName) (?lgName)
ORDER BY DESC (?num)

"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('cnName', 'Canada'), ('lgName', 'corporation'), ('num', '85')]
# [('cnName', 'Canada'), ('lgName', 'joint-stock company'), ('num', '42')]
# [('cnName', 'Canada'), ('lgName', 'public company'), ('num', '18')]
# [('cnName', 'Canada'), ('lgName', 'privately held company'), ('num', '14')]
# [('cnName', 'Canada'), ('lgName', 'company'), ('num', '11')]
# [('cnName', 'Canada'), ('lgName', 'Crown corporation of Canada'), ('num', '11')]
# [('cnName', 'Canada'), ('lgName', 'subsidiary'), ('num', '9')]
# [('cnName', 'Canada'), ('lgName', 'S.A.'), ('num', '5')]
# [('cnName', 'Canada'), ('lgName', 'cooperative'), ('num', '3')]
# [('cnName', 'Canada'), ('lgName', 'GmbH & Co. KG'), ('num', '2')]
# [('cnName', 'Canada'), ('lgName', 'Aktiengesellschaft'), ('num', '2')]
# [('cnName', 'Canada'), ('lgName', 'private limited liability company'), ('num', '2')]
# [('cnName', 'Canada'), ('lgName', 'limited partnership'), ('num', '2')]
# [('cnName', 'Canada'), ('lgName', 'limited liability company'), ('num', '2')]
# [('cnName', 'Canada'), ('lgName', 'nonprofit organization'), ('num', '2')]
# [('cnName', 'Canada'), ('lgName', 'video game development'), ('num', '1')]
# [('cnName', 'Canada'), ('lgName', 'business incubator'), ('num', '1')]
# [('cnName', 'Canada'), ('lgName', 'GmbH'), ('num', '1')]
# [('cnName', 'Canada'), ('lgName', 'holding company'), ('num', '1')]
# [('cnName', 'Canada'), ('lgName', 'Kommanditgesellschaft'), ('num', '1')]
# [('cnName', 'Canada'), ('lgName', 'limited liability partnership'), ('num', '1')]
# [('cnName', 'Canada'), ('lgName', 'Private Enterprise Foundation'), ('num', '1')]
# [('cnName', 'Canada'), ('lgName', 'aktiebolag'), ('num', '1')]
# [('cnName', 'Canada'), ('lgName', 'incorporation'), ('num', '1')]
# [('cnName', 'Canada'), ('lgName', 'Naamloze vennootschap'), ('num', '1')]
# [('cnName', 'Canada'), ('lgName', 'voluntary organization'), ('num', '1')]
# [('cnName', 'Canada'), ('lgName', 'private company limited by shares'), ('num', '1')]
# [('cnName', 'Canada'), ('lgName', 'state-owned enterprise'), ('num', '1')]
# [('cnName', 'Canada'), ('lgName', 'Société par actions simplifiée'), ('num', '1')]
# [('cnName', 'Canada'), ('lgName', 'employee-owned company'), ('num', '1')]
# 30

# %% [markdown]
# Trying to include also UK and USA

# %%
queryString = """

SELECT DISTINCT ?cnName ?lgName COUNT(DISTINCT(?company)) AS ?num
WHERE {


{
# ?company wdt:P17 ?country .
# ?company wdt:P31 wd:Q4830453  . 
# ?company wdt:P1454 ?legalForm .

# ?company <http://schema.org/name> ?cName .
# ?country <http://schema.org/name> ?cnName .
# ?legalForm <http://schema.org/name> ?lgName .


FILTER (?country = wd:Q16)

}
UNION 
{
# ?company wdt:P17 ?country .
# ?company wdt:P31 wd:Q4830453  . 
# ?company wdt:P1454 ?legalForm .

# ?company <http://schema.org/name> ?cName .
# ?country <http://schema.org/name> ?cnName .
# ?legalForm <http://schema.org/name> ?lgName .


FILTER (?country = wd:Q145)
}

} 
GROUP BY (?cnName) (?lgName)
ORDER BY DESC (?num) ASC(?cnName)


"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('cnName', 'United Kingdom'), ('lgName', 'public limited company'), ('num', '240')]
# [('cnName', 'United Kingdom'), ('lgName', 'private company limited by shares'), ('num', '218')]
# [('cnName', 'Canada'), ('lgName', 'corporation'), ('num', '85')]
# [('cnName', 'United Kingdom'), ('lgName', 'privately held company'), ('num', '48')]
# [('cnName', 'United Kingdom'), ('lgName', 'limited company'), ('num', '46')]
# [('cnName', 'Canada'), ('lgName', 'joint-stock company'), ('num', '42')]
# [('cnName', 'United Kingdom'), ('lgName', 'public company'), ('num', '40')]
# [('cnName', 'United Kingdom'), ('lgName', 'joint-stock company'), ('num', '35')]
# [('cnName', 'United Kingdom'), ('lgName', 'private limited liability company'), ('num', '32')]
# [('cnName', 'Canada'), ('lgName', 'public company'), ('num', '18')]
# [('cnName', 'Canada'), ('lgName', 'privately held company'), ('num', '14')]
# [('cnName', 'United Kingdom'), ('lgName', 'Registered Society'), ('num', '13')]
# [('cnName', 'United Kingdom'), ('lgName', 'subsidiary'), ('num', '12')]
# [('cnName', 'Canada'), ('lgName', 'company'), ('num', '11')]
# [('cnName', 'Canada'), ('lgName', 'Crown corporation of Canada'), ('num', '11')]
# [('cnName', 'United Kingdom'), ('lgName', 'S.r.l.'), ('num', '11')]
# [('cnName', 'United Kingdom'), ('lgName', 'company'), ('num', '11')]
# [('cnName', 'Canada'), ('lgName', 'subsidiary'), ('num', '9')]
# [('cnName', 'United Kingdom'), ('lgName', 'S.A.'), ('num', '9')]
# [('cnName', 'United Kingdom'), ('lgName', 'limited liability partnership'), ('num', '8')]
# [('cnName', 'Canada'), ('lgName', 'S.A.'), ('num', '5')]
# [('cnName', 'United Kingdom'), ('lgName', 'joint venture'), ('num', '4')]
# [('cnName', 'Canada'), ('lgName', 'cooperative'), ('num', '3')]
# [('cnName', 'United Kingdom'), ('lgName', 'Kompanie'), ('num', '3')]
# [('cnName', 'United Kingdom'), ('lgName', 'statutory corporation'), ('num', '3')]
# [('cnName', 'United Kingdom'), ('lgName', 'Aktiengesellschaft'), ('num', '3')]
# [('cnName', 'United Kingdom'), ('lgName', 'limited liability company'), ('num', '3')]
# [('cnName', 'Canada'), ('lgName', 'GmbH & Co. KG'), ('num', '2')]
# [('cnName', 'Canada'), ('lgName', 'Aktiengesellschaft'), ('num', '2')]
# [('cnName', 'Canada'), ('lgName', 'private limited liability company'), ('num', '2')]
# [('cnName', 'Canada'), ('lgName', 'limited partnership'), ('num', '2')]
# [('cnName', 'Canada'), ('lgName', 'limited liability company'), ('num', '2')]
# [('cnName', 'Canada'), ('lgName', 'nonprofit organization'), ('num', '2')]
# [('cnName', 'United Kingdom'), ('lgName', 'S.L.'), ('num', '2')]
# [('cnName', 'United Kingdom'), ('lgName', 'GmbH'), ('num', '2')]
# [('cnName', 'United Kingdom'), ('lgName', 'Kommanditgesellschaft auf Aktien'), ('num', '2')]
# [('cnName', 'United Kingdom'), ('lgName', 'Société par actions simplifiée'), ('num', '2')]
# [('cnName', 'United Kingdom'), ('lgName', 'limited partnership'), ('num', '2')]
# [('cnName', 'United Kingdom'), ('lgName', 'trade association'), ('num', '2')]
# [('cnName', 'Canada'), ('lgName', 'video game development'), ('num', '1')]
# [('cnName', 'Canada'), ('lgName', 'business incubator'), ('num', '1')]
# [('cnName', 'Canada'), ('lgName', 'GmbH'), ('num', '1')]
# [('cnName', 'Canada'), ('lgName', 'holding company'), ('num', '1')]
# [('cnName', 'Canada'), ('lgName', 'Kommanditgesellschaft'), ('num', '1')]
# [('cnName', 'Canada'), ('lgName', 'limited liability partnership'), ('num', '1')]
# [('cnName', 'Canada'), ('lgName', 'Private Enterprise Foundation'), ('num', '1')]
# [('cnName', 'Canada'), ('lgName', 'aktiebolag'), ('num', '1')]
# [('cnName', 'Canada'), ('lgName', 'incorporation'), ('num', '1')]
# [('cnName', 'Canada'), ('lgName', 'Naamloze vennootschap'), ('num', '1')]
# [('cnName', 'Canada'), ('lgName', 'voluntary organization'), ('num', '1')]
# [('cnName', 'Canada'), ('lgName', 'private company limited by shares'), ('num', '1')]
# [('cnName', 'Canada'), ('lgName', 'state-owned enterprise'), ('num', '1')]
# [('cnName', 'Canada'), ('lgName', 'Société par actions simplifiée'), ('num', '1')]
# [('cnName', 'Canada'), ('lgName', 'employee-owned company'), ('num', '1')]
# [('cnName', 'United Kingdom'), ('lgName', 'open joint-stock company'), ('num', '1')]
# [('cnName', 'United Kingdom'), ('lgName', 'Besloten vennootschap'), ('num', '1')]
# [('cnName', 'United Kingdom'), ('lgName', 'community interest company'), ('num', '1')]
# [('cnName', 'United Kingdom'), ('lgName', 'mutual organization'), ('num', '1')]
# [('cnName', 'United Kingdom'), ('lgName', 'private company limited by guarantee'), ('num', '1')]
# [('cnName', 'United Kingdom'), ('lgName', 'multinational corporation'), ('num', '1')]
# [('cnName', 'United Kingdom'), ('lgName', 'classification society'), ('num', '1')]
# [('cnName', 'United Kingdom'), ('lgName', 'sociedad anónima'), ('num', '1')]
# [('cnName', 'United Kingdom'), ('lgName', 'société anonyme'), ('num', '1')]
# [('cnName', 'United Kingdom'), ('lgName', 'startup company'), ('num', '1')]
# [('cnName', 'United Kingdom'), ('lgName', 'Société Anonyme'), ('num', '1')]
# [('cnName', 'United Kingdom'), ('lgName', 'Gesellschaft mit beschränkter Haftung'), ('num', '1')]
# [('cnName', 'United Kingdom'), ('lgName', 'enterprise'), ('num', '1')]
# [('cnName', 'United Kingdom'), ('lgName', 'GmbH & Co. KG'), ('num', '1')]
# [('cnName', 'United Kingdom'), ('lgName', 'United Kingdom'), ('num', '1')]
# [('cnName', 'United Kingdom'), ('lgName', 'Emtec Colleges Limited'), ('num', '1')]
# [('cnName', 'United Kingdom'), ('lgName', 'partnership'), ('num', '1')]
# [('cnName', 'United Kingdom'), ('lgName', 'aktieselskab'), ('num', '1')]
# [('cnName', 'United Kingdom'), ('lgName', 'royal charter'), ('num', '1')]
# 73

# %% [markdown]
# **Answer 4**
#
# Here I consider only the top 4 different legal forms for each country: Canada, UK, USA to have a small view of the domanin.
#
# We can see that the "private held company" is present in the top 4 of each country.

# %%
queryString = """

SELECT DISTINCT  ?cnName ?lgName ?num WHERE {
    {
    
SELECT DISTINCT ?cnName ?lgName COUNT(DISTINCT(?company)) AS ?num
WHERE {

# ?company wdt:P17 ?country .
# ?company wdt:P31 wd:Q4830453  . 
# ?company wdt:P1454 ?legalForm .

# ?company <http://schema.org/name> ?cName .
# ?country <http://schema.org/name> ?cnName .
# ?legalForm <http://schema.org/name> ?lgName .


FILTER (?country = wd:Q16)
} 
GROUP BY (?cnName) (?lgName)
ORDER BY DESC (?num)
LIMIT 4

    }
  UNION
   {
     SELECT DISTINCT ?cnName ?lgName COUNT(DISTINCT(?company)) AS ?num
WHERE {

# ?company wdt:P17 ?country .
# ?company wdt:P31 wd:Q4830453  . 
# ?company wdt:P1454 ?legalForm .

# ?company <http://schema.org/name> ?cName .
# ?country <http://schema.org/name> ?cnName .
# ?legalForm <http://schema.org/name> ?lgName .


FILTER (?country = wd:Q145)
} 
GROUP BY (?cnName) (?lgName)
ORDER BY DESC (?num)
LIMIT 4
    }
UNION
{
     SELECT DISTINCT ?cnName ?lgName COUNT(DISTINCT(?company)) AS ?num
WHERE {

# ?company wdt:P17 ?country .
# ?company wdt:P31 wd:Q4830453  . 
# ?company wdt:P1454 ?legalForm .

# ?company <http://schema.org/name> ?cName .
# ?country <http://schema.org/name> ?cnName .
# ?legalForm <http://schema.org/name> ?lgName .


FILTER (?country = wd:Q30)
} 
GROUP BY (?cnName) (?lgName)
ORDER BY DESC (?num)
LIMIT 4
    }
    }
ORDER BY ASC (?cnName)
    """

print("Results")
run_query(queryString)
# Out:
# Results
# [('cnName', 'Canada'), ('lgName', 'corporation'), ('num', '85')]
# [('cnName', 'Canada'), ('lgName', 'joint-stock company'), ('num', '42')]
# [('cnName', 'Canada'), ('lgName', 'public company'), ('num', '18')]
# [('cnName', 'Canada'), ('lgName', 'privately held company'), ('num', '14')]
# [('cnName', 'United Kingdom'), ('lgName', 'public limited company'), ('num', '240')]
# [('cnName', 'United Kingdom'), ('lgName', 'private company limited by shares'), ('num', '218')]
# [('cnName', 'United Kingdom'), ('lgName', 'privately held company'), ('num', '48')]
# [('cnName', 'United Kingdom'), ('lgName', 'limited company'), ('num', '46')]
# [('cnName', 'United States of America'), ('lgName', 'public company'), ('num', '433')]
# [('cnName', 'United States of America'), ('lgName', 'joint-stock company'), ('num', '315')]
# [('cnName', 'United States of America'), ('lgName', 'privately held company'), ('num', '281')]
# [('cnName', 'United States of America'), ('lgName', 'limited liability company'), ('num', '192')]
# 12

# %% [markdown]
# ----------------

# %% [markdown]
# **5 - Analyze the number of employees and other relevant numeric attributes**

# %% [markdown]
# ***5.1 What are the top-10 companies for a given attribute?***
#
# I consider the number of employees and the net profit, but the query can be personalized leaving only the attribute we like.

# %%
queryString = """
SELECT DISTINCT ?cName (?obj1 AS ?Num_Asset) (?obj2 AS ?num_Employees) (?obj5 AS ?est_value) (?obj6 AS ?net_profit) (?obj7 AS ?tot_rev) (GROUP_CONCAT(DISTINCT ?ownby;separator='; ') AS ?OwnedBy )(?parentO AS ?Parent) 
WHERE { 

# ?company wdt:P31 wd:Q4830453  .

OPTIONAL {?company wdt:P4103 ?obj1 .} #num Asset
OPTIONAL {?company wdt:P1128 ?obj2 .} #num employees
OPTIONAL {?company wdt:P127 ?obj3 . #owned by
            # ?obj3 <http://schema.org/name> ?ownby .}
OPTIONAL {?company wdt:P749 ?obj4 . #parent organization
            # ?obj4 <http://schema.org/name> ?parentO .}
OPTIONAL {?company wdt:P8340 ?obj5 .} #est value

OPTIONAL {?company wdt:P2295 ?obj6 .} #net profit

OPTIONAL {?company wdt:P2139 ?obj7 .} #tot revenue

# ?company <http://schema.org/name> ?cName.
} 
ORDER BY DESC (?num_Employees)
LIMIT 50
"""

print("Results")
run_query(queryString)

# %% [markdown]
# *TOP 10 for the number of EMPLOYEES*

# %%
queryString = """
SELECT DISTINCT ?cName (?obj2 AS ?num_Employees)
WHERE { 

# ?company wdt:P31 wd:Q4830453  .

OPTIONAL {?company wdt:P1128 ?obj2 .} #num employees

# ?company <http://schema.org/name> ?cName.
} 
ORDER BY DESC (?num_Employees)
LIMIT 10
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('cName', 'Rikushet'), ('num_Employees', 'nodeID://b70728')]
# [('cName', 'Walmart'), ('num_Employees', '2500000')]
# [('cName', 'China National Petroleum Corporation'), ('num_Employees', '1589508')]
# [('cName', 'State Grid Corporation of China'), ('num_Employees', '1581000')]
# [('cName', 'Amazon'), ('num_Employees', '1298000')]
# [('cName', 'Randstad N.V.'), ('num_Employees', '658580')]
# [('cName', 'Foxconn'), ('num_Employees', '618460')]
# [('cName', 'G4S'), ('num_Employees', '618260')]
# [('cName', 'RAO UES'), ('num_Employees', '577000')]
# [('cName', 'DHL'), ('num_Employees', '570000')]
# 10

# %% [markdown]
# *TOP 10 for the net profit*, one of the most important attribute for a business

# %%
queryString = """
SELECT DISTINCT ?cName (?obj6 AS ?net_profit)
WHERE { 

# ?company wdt:P31 wd:Q4830453  .

OPTIONAL {?company wdt:P2295 ?obj6 .} #net profit

# ?company <http://schema.org/name> ?cName.
} 
ORDER BY DESC (?net_profit)
LIMIT 10
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('cName', 'Samsung Electronics'), ('net_profit', '22730000000000')]
# [('cName', 'Toyota'), ('net_profit', '2312694000000')]
# [('cName', 'Central Japan Railway Company'), ('net_profit', '391624000000')]
# [('cName', 'Saudi Aramco'), ('net_profit', '330693000000')]
# [('cName', 'Leica Camera'), ('net_profit', 'nodeID://b62766')]
# [('cName', 'SoftBank'), ('net_profit', '1237812000000')]
# [('cName', 'Sberbank of Russia'), ('net_profit', '760300000000')]
# [('cName', 'Industrial and Commercial Bank of China'), ('net_profit', '317685000000')]
# [('cName', 'East Japan Railway Company'), ('net_profit', '279435000000')]
# [('cName', 'MOL Group'), ('net_profit', '251655000000')]
# 10

# %% [markdown]
# ------------------

# %% [markdown]
# ***5.2 For which companies is defined some form of income or market capitalization or total assets? What is the min, max, and average in each category and country?***

# %%
queryString = """
SELECT DISTINCT ?lgName
WHERE {

# ?company wdt:P17 ?country .
# ?company wdt:P31 wd:Q4830453  . 
# ?company wdt:P1454 ?legalForm .

# ?company wdt:P2403 ?totasset .

# ?company <http://schema.org/name> ?cName .

# ?legalForm <http://schema.org/name> ?lgName .


FILTER (?country = wd:Q30 || ?country = wd:Q145 || ?country = wd:Q16)
} 

ORDER BY ASC(?cnName)

"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('lgName', 'public limited company')]
# [('lgName', 'public company')]
# [('lgName', 'limited liability company')]
# [('lgName', 'privately held company')]
# [('lgName', 'U.S. corporation')]
# [('lgName', 'Delaware corporation')]
# [('lgName', 'limited partnership')]
# [('lgName', 'incorporation')]
# [('lgName', 'government-sponsored enterprise')]
# [('lgName', 'joint-stock company')]
# [('lgName', 'corporation')]
# [('lgName', 'private company')]
# [('lgName', 'Washington corporation')]
# 13

# %% [markdown]
# **Answer 5.2**
#
# From the previous query, cosidering only the three countries, legal form like public limited company,corporation,ecc.. have the "total asset" value.

# %% [markdown]
# Testing for Canada, Q16

# %%
queryString = """
SELECT DISTINCT ?lgName MAX(?totasset)
WHERE {

# ?company wdt:P17  wd:Q16 .
# ?company wdt:P31 wd:Q4830453  . 
# ?company wdt:P1454 ?legalForm .

# ?company wdt:P2403 ?totasset .

# ?company <http://schema.org/name> ?cName .

# ?legalForm <http://schema.org/name> ?lgName .


} 

ORDER BY ASC(?cnName)

"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('lgName', 'corporation')]
# 1

# %% [markdown]
# Using market capitaliaztion?

# %%
queryString = """
SELECT DISTINCT ?lgName MAX(?marketcap)
WHERE {

# ?company wdt:P17  wd:Q16 .
# ?company wdt:P31 wd:Q4830453  . 
# ?company wdt:P1454 ?legalForm .

# ?company wdt:P2226 ?marketcap .

# ?company <http://schema.org/name> ?cName .

# ?legalForm <http://schema.org/name> ?lgName .


} 

ORDER BY ASC(?cnName)

"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('lgName', 'corporation'), ('callret-1', '45900000000')]
# [('lgName', 'public company'), ('callret-1', '648532358')]
# 2

# %% [markdown]
# I will use market cap entity. So, I repeat the previous query.

# %%
queryString = """
SELECT DISTINCT ?lgName
WHERE {

# ?company wdt:P17 ?country .
# ?company wdt:P31 wd:Q4830453  . 
# ?company wdt:P1454 ?legalForm .

# ?company wdt:P2226 ?marketcap .

# ?company <http://schema.org/name> ?cName .

# ?legalForm <http://schema.org/name> ?lgName .


FILTER (?country = wd:Q30 || ?country = wd:Q145 || ?country = wd:Q16)
} 

ORDER BY ASC(?cnName)

"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('lgName', 'public limited company')]
# [('lgName', 'public company')]
# [('lgName', 'privately held company')]
# [('lgName', 'U.S. corporation')]
# [('lgName', 'Delaware corporation')]
# [('lgName', 'incorporation')]
# [('lgName', 'joint-stock company')]
# [('lgName', 'corporation')]
# [('lgName', 'Washington corporation')]
# 9

# %% [markdown]
# There are 9 different legal forms that have a market cap value

# %%
queryString = """
SELECT DISTINCT ?lgName (MAX(?marketcap) AS ?max_mcap) (MIN(?marketcap) AS ?min_mcap) (AVG(?marketcap) AS ?avg_mcap)
WHERE {

# ?company wdt:P17 ?country .
# ?company wdt:P31 wd:Q4830453  . 
# ?company wdt:P1454 ?legalForm .

# ?company wdt:P2226 ?marketcap .

# ?company <http://schema.org/name> ?cName .
# ?country <http://schema.org/name> ?cnName .

# ?legalForm <http://schema.org/name> ?lgName .


FILTER (?country = wd:Q30 || ?country = wd:Q145 || ?country = wd:Q16)
} 
GROUP BY (?lgName)

"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('lgName', 'Washington corporation'), ('max_mcap', '2270000000000'), ('min_mcap', '407000000000'), ('avg_mcap', '1649250000000')]
# [('lgName', 'U.S. corporation'), ('max_mcap', '2470000000000'), ('min_mcap', '41070000000'), ('avg_mcap', '985799166666.666666666666667')]
# [('lgName', 'public limited company'), ('max_mcap', '185400000000'), ('min_mcap', '47000000000'), ('avg_mcap', '116200000000')]
# [('lgName', 'joint-stock company'), ('max_mcap', '650340000000'), ('min_mcap', '3960000000'), ('avg_mcap', '171168050000')]
# [('lgName', 'privately held company'), ('max_mcap', '62500000000'), ('min_mcap', '62500000000'), ('avg_mcap', '62500000000')]
# [('lgName', 'Delaware corporation'), ('max_mcap', '1900000000000'), ('min_mcap', '1530000000'), ('avg_mcap', '345468080580.777777777777778')]
# [('lgName', 'corporation'), ('max_mcap', '70600000000'), ('min_mcap', '6882000000'), ('avg_mcap', '41127333333.333333333333333')]
# [('lgName', 'public company'), ('max_mcap', '2270000000000'), ('min_mcap', '157104000'), ('avg_mcap', '304202436006.509090909090909')]
# [('lgName', 'incorporation'), ('max_mcap', '1670000000000'), ('min_mcap', '163000000000'), ('avg_mcap', '1093250000000')]
# 9

# %% [markdown]
# Trying to split into the different countries. One query for each attribute I'm looking for: One query for the max market cap, one for min market cap and another one for the average.

# %%
Max Market cap

# %%
queryString = """
SELECT DISTINCT ?cnName ?cName ?lgName ?max_mcap
WHERE {

# ?company wdt:P17 ?country .
# ?company wdt:P1454 ?legalForm .

# ?company wdt:P2226 ?marketcap1 .

# ?company <http://schema.org/name> ?cName .
# ?country <http://schema.org/name> ?cnName .

# ?legalForm <http://schema.org/name> ?lgName .

FILTER (?marketcap1 = ?max_mcap)

{
SELECT DISTINCT ?country ?lgName (MAX(?marketcap) AS ?max_mcap)
WHERE {

# ?company wdt:P17 ?country .
# ?company wdt:P31 wd:Q4830453  . 
# ?company wdt:P1454 ?legalForm .

# ?company wdt:P2226 ?marketcap .


# ?legalForm <http://schema.org/name> ?lgName .


FILTER (?country = wd:Q30 || ?country = wd:Q145 || ?country = wd:Q16)


}
GROUP BY (?lgName) (?country)

} 

}
ORDER BY ASC (?cnName) ASC(?lgName)
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('cnName', 'Canada'), ('cName', 'Thomson Reuters'), ('lgName', 'corporation'), ('max_mcap', '45900000000')]
# [('cnName', 'Canada'), ('cName', 'Cineplex Entertainment'), ('lgName', 'public company'), ('max_mcap', '648532358')]
# [('cnName', 'United Kingdom'), ('cName', 'HSBC'), ('lgName', 'public limited company'), ('max_mcap', '185400000000')]
# [('cnName', 'United States of America'), ('cName', 'Alphabet Inc.'), ('lgName', 'Delaware corporation'), ('max_mcap', '1900000000000')]
# [('cnName', 'United States of America'), ('cName', 'Apple Inc.'), ('lgName', 'U.S. corporation'), ('max_mcap', '2470000000000')]
# [('cnName', 'United States of America'), ('cName', 'Microsoft'), ('lgName', 'Washington corporation'), ('max_mcap', '2270000000000')]
# [('cnName', 'United States of America'), ('cName', 'eBay'), ('lgName', 'corporation'), ('max_mcap', '70600000000')]
# [('cnName', 'United States of America'), ('cName', 'Amazon'), ('lgName', 'incorporation'), ('max_mcap', '1670000000000')]
# [('cnName', 'United States of America'), ('cName', 'Berkshire Hathaway'), ('lgName', 'joint-stock company'), ('max_mcap', '650340000000')]
# [('cnName', 'United States of America'), ('cName', 'Uber Technology'), ('lgName', 'privately held company'), ('max_mcap', '62500000000')]
# [('cnName', 'United States of America'), ('cName', 'Microsoft'), ('lgName', 'public company'), ('max_mcap', '2270000000000')]
# 11

# %%
Min Market cap

# %%
queryString = """
SELECT DISTINCT ?cnName ?cName ?lgName ?min_mcap
WHERE {

# ?company wdt:P17 ?country .
# ?company wdt:P1454 ?legalForm .

# ?company wdt:P2226 ?marketcap1 .

# ?company <http://schema.org/name> ?cName .
# ?country <http://schema.org/name> ?cnName .

# ?legalForm <http://schema.org/name> ?lgName .

FILTER (?marketcap1 = ?max_mcap)

{
SELECT DISTINCT ?country ?lgName (MIN(?marketcap) AS ?min_mcap)
WHERE {

# ?company wdt:P17 ?country .
# ?company wdt:P31 wd:Q4830453  . 
# ?company wdt:P1454 ?legalForm .

# ?company wdt:P2226 ?marketcap .


# ?legalForm <http://schema.org/name> ?lgName .


FILTER (?country = wd:Q30 || ?country = wd:Q145 || ?country = wd:Q16)


}
GROUP BY (?lgName) (?country)
} 

}
ORDER BY ASC (?cnName) ASC(?lgName)
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('cnName', 'Canada'), ('cName', 'BlackBerry'), ('lgName', 'corporation'), ('min_mcap', '6882000000')]
# [('cnName', 'Canada'), ('cName', 'Thomson Reuters'), ('lgName', 'corporation'), ('min_mcap', '6882000000')]
# [('cnName', 'Canada'), ('cName', 'Cineplex Entertainment'), ('lgName', 'public company'), ('min_mcap', '648532358')]
# [('cnName', 'United Kingdom'), ('cName', 'HSBC'), ('lgName', 'public limited company'), ('min_mcap', '47000000000')]
# [('cnName', 'United Kingdom'), ('cName', 'Lloyds Banking Group'), ('lgName', 'public limited company'), ('min_mcap', '47000000000')]
# [('cnName', 'United States of America'), ('cName', 'Intel'), ('lgName', 'Delaware corporation'), ('min_mcap', '1530000000')]
# [('cnName', 'United States of America'), ('cName', 'Alphabet Inc.'), ('lgName', 'Delaware corporation'), ('min_mcap', '1530000000')]
# [('cnName', 'United States of America'), ('cName', 'Nvidia'), ('lgName', 'Delaware corporation'), ('min_mcap', '1530000000')]
# [('cnName', 'United States of America'), ('cName', 'Pfizer'), ('lgName', 'Delaware corporation'), ('min_mcap', '1530000000')]
# [('cnName', 'United States of America'), ('cName', 'General Motors'), ('lgName', 'Delaware corporation'), ('min_mcap', '1530000000')]
# [('cnName', 'United States of America'), ('cName', 'Goldman Sachs'), ('lgName', 'Delaware corporation'), ('min_mcap', '1530000000')]
# [('cnName', 'United States of America'), ('cName', 'McDonald’s'), ('lgName', 'Delaware corporation'), ('min_mcap', '1530000000')]
# [('cnName', 'United States of America'), ('cName', 'Walmart'), ('lgName', 'Delaware corporation'), ('min_mcap', '1530000000')]
# [('cnName', 'United States of America'), ('cName', 'The Home Depot'), ('lgName', 'Delaware corporation'), ('min_mcap', '1530000000')]
# [('cnName', 'United States of America'), ('cName', 'Ford Motor Company'), ('lgName', 'Delaware corporation'), ('min_mcap', '1530000000')]
# [('cnName', 'United States of America'), ('cName', 'Gilead Sciences'), ('lgName', 'Delaware corporation'), ('min_mcap', '1530000000')]
# [('cnName', 'United States of America'), ('cName', 'U.S. Steel'), ('lgName', 'Delaware corporation'), ('min_mcap', '1530000000')]
# [('cnName', 'United States of America'), ('cName', 'Boeing'), ('lgName', 'U.S. corporation'), ('min_mcap', '41070000000')]
# [('cnName', 'United States of America'), ('cName', 'Apple Inc.'), ('lgName', 'U.S. corporation'), ('min_mcap', '41070000000')]
# [('cnName', 'United States of America'), ('cName', 'Lockheed Martin'), ('lgName', 'U.S. corporation'), ('min_mcap', '41070000000')]
# [('cnName', 'United States of America'), ('cName', 'ExxonMobil'), ('lgName', 'U.S. corporation'), ('min_mcap', '41070000000')]
# [('cnName', 'United States of America'), ('cName', 'American Express'), ('lgName', 'U.S. corporation'), ('min_mcap', '41070000000')]
# [('cnName', 'United States of America'), ('cName', 'Northrop Grumman'), ('lgName', 'U.S. corporation'), ('min_mcap', '41070000000')]
# [('cnName', 'United States of America'), ('cName', 'Raytheon Company'), ('lgName', 'U.S. corporation'), ('min_mcap', '41070000000')]
# [('cnName', 'United States of America'), ('cName', 'Microsoft'), ('lgName', 'Washington corporation'), ('min_mcap', '407000000000')]
# [('cnName', 'United States of America'), ('cName', 'eBay'), ('lgName', 'corporation'), ('min_mcap', '70600000000')]
# [('cnName', 'United States of America'), ('cName', 'Amazon'), ('lgName', 'incorporation'), ('min_mcap', '163000000000')]
# [('cnName', 'United States of America'), ('cName', '21st Century Fox'), ('lgName', 'joint-stock company'), ('min_mcap', '3960000000')]
# [('cnName', 'United States of America'), ('cName', 'Bank of America'), ('lgName', 'joint-stock company'), ('min_mcap', '3960000000')]
# [('cnName', 'United States of America'), ('cName', 'Viacom'), ('lgName', 'joint-stock company'), ('min_mcap', '3960000000')]
# [('cnName', 'United States of America'), ('cName', 'Berkshire Hathaway'), ('lgName', 'joint-stock company'), ('min_mcap', '3960000000')]
# [('cnName', 'United States of America'), ('cName', 'Visa Inc.'), ('lgName', 'joint-stock company'), ('min_mcap', '3960000000')]
# [('cnName', 'United States of America'), ('cName', 'IBM'), ('lgName', 'joint-stock company'), ('min_mcap', '3960000000')]
# [('cnName', 'United States of America'), ('cName', 'WarnerMedia'), ('lgName', 'joint-stock company'), ('min_mcap', '3960000000')]
# [('cnName', 'United States of America'), ('cName', 'AT&T'), ('lgName', 'joint-stock company'), ('min_mcap', '3960000000')]
# [('cnName', 'United States of America'), ('cName', 'Nike'), ('lgName', 'joint-stock company'), ('min_mcap', '3960000000')]
# [('cnName', 'United States of America'), ('cName', 'Advanced Micro Devices'), ('lgName', 'joint-stock company'), ('min_mcap', '3960000000')]
# [('cnName', 'United States of America'), ('cName', 'State Street Corporation'), ('lgName', 'joint-stock company'), ('min_mcap', '3960000000')]
# [('cnName', 'United States of America'), ('cName', 'Activision Blizzard'), ('lgName', 'joint-stock company'), ('min_mcap', '3960000000')]
# [('cnName', 'United States of America'), ('cName', 'Mastercard'), ('lgName', 'joint-stock company'), ('min_mcap', '3960000000')]
# [('cnName', 'United States of America'), ('cName', 'Abbott Laboratories'), ('lgName', 'joint-stock company'), ('min_mcap', '3960000000')]
# [('cnName', 'United States of America'), ('cName', 'PepsiCo'), ('lgName', 'joint-stock company'), ('min_mcap', '3960000000')]
# [('cnName', 'United States of America'), ('cName', 'Cushman & Wakefield'), ('lgName', 'joint-stock company'), ('min_mcap', '3960000000')]
# [('cnName', 'United States of America'), ('cName', 'Humana'), ('lgName', 'joint-stock company'), ('min_mcap', '3960000000')]
# [('cnName', 'United States of America'), ('cName', 'Akamai Technologies'), ('lgName', 'joint-stock company'), ('min_mcap', '3960000000')]
# [('cnName', 'United States of America'), ('cName', 'Uber Technology'), ('lgName', 'privately held company'), ('min_mcap', '62500000000')]
# [('cnName', 'United States of America'), ('cName', 'Publix'), ('lgName', 'privately held company'), ('min_mcap', '62500000000')]
# [('cnName', 'United States of America'), ('cName', 'Cree Inc.'), ('lgName', 'public company'), ('min_mcap', '157104000')]
# [('cnName', 'United States of America'), ('cName', 'The Hartford'), ('lgName', 'public company'), ('min_mcap', '157104000')]
# [('cnName', 'United States of America'), ('cName', '21st Century Fox'), ('lgName', 'public company'), ('min_mcap', '157104000')]
# [('cnName', 'United States of America'), ('cName', 'Bank of America'), ('lgName', 'public company'), ('min_mcap', '157104000')]
# [('cnName', 'United States of America'), ('cName', 'Delta Air Lines'), ('lgName', 'public company'), ('min_mcap', '157104000')]
# [('cnName', 'United States of America'), ('cName', 'Uber Technology'), ('lgName', 'public company'), ('min_mcap', '157104000')]
# [('cnName', 'United States of America'), ('cName', 'MicroStrategy'), ('lgName', 'public company'), ('min_mcap', '157104000')]
# [('cnName', 'United States of America'), ('cName', 'Hewlett Packard Enterprise'), ('lgName', 'public company'), ('min_mcap', '157104000')]
# [('cnName', 'United States of America'), ('cName', 'PayPal'), ('lgName', 'public company'), ('min_mcap', '157104000')]
# [('cnName', 'United States of America'), ('cName', 'BlackRock'), ('lgName', 'public company'), ('min_mcap', '157104000')]
# [('cnName', 'United States of America'), ('cName', 'Microsoft'), ('lgName', 'public company'), ('min_mcap', '157104000')]
# [('cnName', 'United States of America'), ('cName', 'Oracle'), ('lgName', 'public company'), ('min_mcap', '157104000')]
# [('cnName', 'United States of America'), ('cName', 'IBM'), ('lgName', 'public company'), ('min_mcap', '157104000')]
# [('cnName', 'United States of America'), ('cName', 'Pfizer'), ('lgName', 'public company'), ('min_mcap', '157104000')]
# [('cnName', 'United States of America'), ('cName', 'WarnerMedia'), ('lgName', 'public company'), ('min_mcap', '157104000')]
# [('cnName', 'United States of America'), ('cName', 'AT&T'), ('lgName', 'public company'), ('min_mcap', '157104000')]
# [('cnName', 'United States of America'), ('cName', 'General Electric'), ('lgName', 'public company'), ('min_mcap', '157104000')]
# [('cnName', 'United States of America'), ('cName', 'JPMorgan Chase'), ('lgName', 'public company'), ('min_mcap', '157104000')]
# [('cnName', 'United States of America'), ('cName', '3M'), ('lgName', 'public company'), ('min_mcap', '157104000')]
# [('cnName', 'United States of America'), ('cName', 'Merck & Co.'), ('lgName', 'public company'), ('min_mcap', '157104000')]
# [('cnName', 'United States of America'), ('cName', 'Johnson & Johnson'), ('lgName', 'public company'), ('min_mcap', '157104000')]
# [('cnName', 'United States of America'), ('cName', 'Verizon'), ('lgName', 'public company'), ('min_mcap', '157104000')]
# [('cnName', 'United States of America'), ('cName', 'Walmart'), ('lgName', 'public company'), ('min_mcap', '157104000')]
# [('cnName', 'United States of America'), ('cName', 'Advanced Micro Devices'), ('lgName', 'public company'), ('min_mcap', '157104000')]
# [('cnName', 'United States of America'), ('cName', 'State Street Corporation'), ('lgName', 'public company'), ('min_mcap', '157104000')]
# [('cnName', 'United States of America'), ('cName', 'Schlumberger'), ('lgName', 'public company'), ('min_mcap', '157104000')]
# [('cnName', 'United States of America'), ('cName', 'Tesla, Inc.'), ('lgName', 'public company'), ('min_mcap', '157104000')]
# [('cnName', 'United States of America'), ('cName', 'Citigroup'), ('lgName', 'public company'), ('min_mcap', '157104000')]
# [('cnName', 'United States of America'), ('cName', 'Dell Inc.'), ('lgName', 'public company'), ('min_mcap', '157104000')]
# [('cnName', 'United States of America'), ('cName', 'Corning Inc.'), ('lgName', 'public company'), ('min_mcap', '157104000')]
# [('cnName', 'United States of America'), ('cName', 'T. Rowe Price'), ('lgName', 'public company'), ('min_mcap', '157104000')]
# [('cnName', 'United States of America'), ('cName', 'HP Inc.'), ('lgName', 'public company'), ('min_mcap', '157104000')]
# [('cnName', 'United States of America'), ('cName', 'Avon Products Inc'), ('lgName', 'public company'), ('min_mcap', '157104000')]
# [('cnName', 'United States of America'), ('cName', 'Airbnb'), ('lgName', 'public company'), ('min_mcap', '157104000')]
# [('cnName', 'United States of America'), ('cName', 'Biomx'), ('lgName', 'public company'), ('min_mcap', '157104000')]
# [('cnName', 'United States of America'), ('cName', 'Akamai Technologies'), ('lgName', 'public company'), ('min_mcap', '157104000')]
# [('cnName', 'United States of America'), ('cName', 'MEDLEY'), ('lgName', 'public company'), ('min_mcap', '157104000')]
# [('cnName', 'United States of America'), ('cName', 'CIM Commercial Trust Corporation'), ('lgName', 'public company'), ('min_mcap', '157104000')]
# [('cnName', 'United States of America'), ('cName', 'PowerFleet'), ('lgName', 'public company'), ('min_mcap', '157104000')]
# [('cnName', 'United States of America'), ('cName', 'Lineage Cell Therapeutics'), ('lgName', 'public company'), ('min_mcap', '157104000')]
# 87

# %% [markdown]
# As we can see there are many companies with the same minimun market cap. This mean probably that those are approximated values.
# I notice that Alphabet(Google ndr) is preset in both results set, max and min market cap. Maybe this is due different resources or different moment in the company history.
#
# Explore the property market cap

# %%
queryString = """
SELECT DISTINCT  ?p ?pName ?o
WHERE {

wd:P2226 ?p ?o .

OPTIONAL{?p <http://schema.org/name> ?pName .}

}

"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('o', 'http://www.wikidata.org/entity/Q21451178')]
# [('p', 'http://www.wikidata.org/prop/direct/P1896'), ('pName', 'source website for the property'), ('o', 'http://finance.yahoo.com')]
# [('p', 'http://www.wikidata.org/prop/direct/P1629'), ('pName', 'Wikidata item of this property'), ('o', 'http://www.wikidata.org/entity/Q471719')]
# [('p', 'http://www.wikidata.org/prop/direct/P1855'), ('pName', 'Wikidata property example'), ('o', 'http://www.wikidata.org/entity/Q312')]
# [('p', 'http://www.wikidata.org/prop/direct/P2302'), ('pName', 'property constraint'), ('o', 'http://www.wikidata.org/entity/Q53869507')]
# [('p', 'http://www.wikidata.org/prop/direct/P2302'), ('pName', 'property constraint'), ('o', 'http://www.wikidata.org/entity/Q21510851')]
# [('p', 'http://www.wikidata.org/prop/direct/P2302'), ('pName', 'property constraint'), ('o', 'http://www.wikidata.org/entity/Q21514353')]
# [('p', 'http://www.wikidata.org/prop/direct/P2302'), ('pName', 'property constraint'), ('o', 'http://www.wikidata.org/entity/Q19474404')]
# [('p', 'http://www.wikidata.org/prop/direct/P2302'), ('pName', 'property constraint'), ('o', 'http://www.wikidata.org/entity/Q54554025')]
# [('p', 'http://www.wikidata.org/prop/direct/P2302'), ('pName', 'property constraint'), ('o', 'http://www.wikidata.org/entity/Q21510856')]
# [('p', 'http://www.wikidata.org/prop/direct/P2875'), ('pName', 'property usage tracking category'), ('o', 'http://www.wikidata.org/entity/Q23909076')]
# [('p', 'http://www.wikidata.org/prop/direct/P3254'), ('pName', 'property proposal discussion'), ('o', 'https://www.wikidata.org/wiki/Wikidata:Property_proposal/Archive/38#P2226')]
# [('p', 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), ('o', 'http://wikiba.se/ontology#Property')]
# [('p', 'http://schema.org/name'), ('o', 'market capitalization')]
# [('p', 'http://wikiba.se/ontology#directClaimNormalized'), ('o', 'http://www.wikidata.org/prop/direct-normalized/P2226')]
# [('p', 'http://wikiba.se/ontology#qualifierValueNormalized'), ('o', 'http://www.wikidata.org/prop/qualifier/value-normalized/P2226')]
# [('p', 'http://wikiba.se/ontology#referenceValueNormalized'), ('o', 'http://www.wikidata.org/prop/reference/value-normalized/P2226')]
# [('p', 'http://wikiba.se/ontology#statementValueNormalized'), ('o', 'http://www.wikidata.org/prop/statement/value-normalized/P2226')]
# [('p', 'http://wikiba.se/ontology#claim'), ('o', 'http://www.wikidata.org/prop/P2226')]
# [('p', 'http://wikiba.se/ontology#directClaim'), ('o', 'http://www.wikidata.org/prop/direct/P2226')]
# [('p', 'http://wikiba.se/ontology#novalue'), ('o', 'http://www.wikidata.org/prop/novalue/P2226')]
# [('p', 'http://wikiba.se/ontology#propertyType'), ('o', 'http://wikiba.se/ontology#Quantity')]
# [('p', 'http://wikiba.se/ontology#qualifier'), ('o', 'http://www.wikidata.org/prop/qualifier/P2226')]
# [('p', 'http://wikiba.se/ontology#qualifierValue'), ('o', 'http://www.wikidata.org/prop/qualifier/value/P2226')]
# [('p', 'http://wikiba.se/ontology#reference'), ('o', 'http://www.wikidata.org/prop/reference/P2226')]
# [('p', 'http://wikiba.se/ontology#referenceValue'), ('o', 'http://www.wikidata.org/prop/reference/value/P2226')]
# [('p', 'http://wikiba.se/ontology#statementProperty'), ('o', 'http://www.wikidata.org/prop/statement/P2226')]
# [('p', 'http://wikiba.se/ontology#statementValue'), ('o', 'http://www.wikidata.org/prop/statement/value/P2226')]
# 28

# %%
queryString = """
SELECT DISTINCT ?cnName ?cName ?lgName ?cap
WHERE {

# ?company wdt:P17 ?country .
# ?company wdt:P1454 ?legalForm .

# ?company wdt:P2226 ?marketcap1 .

# ?company <http://schema.org/name> ?cName .
# ?country <http://schema.org/name> ?cnName .

# ?legalForm <http://schema.org/name> ?lgName .

FILTER (?marketcap1 = ?cap)

{
SELECT DISTINCT ?country ?lgName (MAX(?marketcap) AS ?cap)
WHERE {

# ?company wdt:P17 ?country .
# ?company wdt:P31 wd:Q4830453  . 
# ?company wdt:P1454 ?legalForm .

# ?company wdt:P2226 ?marketcap .


# ?legalForm <http://schema.org/name> ?lgName .


FILTER (?country = wd:Q30 || ?country = wd:Q145 || ?country = wd:Q16)


}
GROUP BY (?lgName) (?country)

} 
UNION
{
SELECT DISTINCT ?country ?lgName (MIN(?marketcap) AS ?cap)
WHERE {

# ?company wdt:P17 ?country .
# ?company wdt:P31 wd:Q4830453  . 
# ?company wdt:P1454 ?legalForm .

# ?company wdt:P2226 ?marketcap .


# ?legalForm <http://schema.org/name> ?lgName .


FILTER (?country = wd:Q30 || ?country = wd:Q145 || ?country = wd:Q16)


}
GROUP BY (?lgName) (?country)

} 


}
ORDER BY ASC (?cnName) ASC(?lgName)
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('cnName', 'Canada'), ('cName', 'Thomson Reuters'), ('lgName', 'corporation'), ('cap', '45900000000')]
# [('cnName', 'Canada'), ('cName', 'BlackBerry'), ('lgName', 'corporation'), ('cap', '6882000000')]
# [('cnName', 'Canada'), ('cName', 'Cineplex Entertainment'), ('lgName', 'public company'), ('cap', '648532358')]
# [('cnName', 'United Kingdom'), ('cName', 'HSBC'), ('lgName', 'public limited company'), ('cap', '185400000000')]
# [('cnName', 'United Kingdom'), ('cName', 'Lloyds Banking Group'), ('lgName', 'public limited company'), ('cap', '47000000000')]
# [('cnName', 'United States of America'), ('cName', 'Alphabet Inc.'), ('lgName', 'Delaware corporation'), ('cap', '1900000000000')]
# [('cnName', 'United States of America'), ('cName', 'Alphabet Inc.'), ('lgName', 'Delaware corporation'), ('cap', '1530000000')]
# [('cnName', 'United States of America'), ('cName', 'Apple Inc.'), ('lgName', 'U.S. corporation'), ('cap', '2470000000000')]
# [('cnName', 'United States of America'), ('cName', 'Northrop Grumman'), ('lgName', 'U.S. corporation'), ('cap', '41070000000')]
# [('cnName', 'United States of America'), ('cName', 'Microsoft'), ('lgName', 'Washington corporation'), ('cap', '2270000000000')]
# [('cnName', 'United States of America'), ('cName', 'Microsoft'), ('lgName', 'Washington corporation'), ('cap', '407000000000')]
# [('cnName', 'United States of America'), ('cName', 'eBay'), ('lgName', 'corporation'), ('cap', '70600000000')]
# [('cnName', 'United States of America'), ('cName', 'Amazon'), ('lgName', 'incorporation'), ('cap', '1670000000000')]
# [('cnName', 'United States of America'), ('cName', 'Amazon'), ('lgName', 'incorporation'), ('cap', '163000000000')]
# [('cnName', 'United States of America'), ('cName', 'Berkshire Hathaway'), ('lgName', 'joint-stock company'), ('cap', '650340000000')]
# [('cnName', 'United States of America'), ('cName', 'Cushman & Wakefield'), ('lgName', 'joint-stock company'), ('cap', '3960000000')]
# [('cnName', 'United States of America'), ('cName', 'Uber Technology'), ('lgName', 'privately held company'), ('cap', '62500000000')]
# [('cnName', 'United States of America'), ('cName', 'Microsoft'), ('lgName', 'public company'), ('cap', '2270000000000')]
# [('cnName', 'United States of America'), ('cName', 'MEDLEY'), ('lgName', 'public company'), ('cap', '157104000')]
# 19

# %%
queryString = """
SELECT DISTINCT ?cnName ?cmpn ?lgName ?capitalization WHERE {
{
SELECT DISTINCT ?cnName ?cmpn ?lgName ?max_mcap
WHERE {

# ?company wdt:P17 ?country .
# ?company wdt:P1454 ?legalForm .

# ?company wdt:P2226 ?marketcap1 .

# ?company <http://schema.org/name> ?cName1 .
# ?country <http://schema.org/name> ?cnName .

# ?legalForm <http://schema.org/name> ?lgName .

FILTER (?marketcap1 = ?max_mcap)

BIND (?cName1 AS ?cmpn)

{
SELECT DISTINCT ?country ?lgName (MAX(?marketcap) AS ?max_mcap)
WHERE {

# ?company wdt:P17 ?country .
# ?company wdt:P31 wd:Q4830453  . 
# ?company wdt:P1454 ?legalForm .

# ?company wdt:P2226 ?marketcap .


# ?legalForm <http://schema.org/name> ?lgName .


FILTER (?country = wd:Q30 || ?country = wd:Q145 || ?country = wd:Q16)


}
GROUP BY (?lgName) (?country)

} 

}
ORDER BY ASC (?cnName) ASC(?lgName)
}
UNION
{
SELECT DISTINCT ?cnName ?cmpn ?lgName ?min_mcap
WHERE {

# ?company wdt:P17 ?country .
# ?company wdt:P1454 ?legalForm .

# ?company wdt:P2226 ?marketcap2 .

# ?company <http://schema.org/name> ?cName2 .
# ?country <http://schema.org/name> ?cnName .

# ?legalForm <http://schema.org/name> ?lgName .

FILTER (?marketcap2 = ?min_mcap)

BIND (?cName2 AS ?cmpn)

{
SELECT DISTINCT ?country ?lgName (MIN(?marketcap) AS ?min_mcap)
WHERE {

# ?company wdt:P17 ?country .
# ?company wdt:P31 wd:Q4830453  . 
# ?company wdt:P1454 ?legalForm .

# ?company wdt:P2226 ?marketcap .


# ?legalForm <http://schema.org/name> ?lgName .


FILTER (?country = wd:Q30 || ?country = wd:Q145 || ?country = wd:Q16)


}
GROUP BY (?lgName) (?country)

} 

}
ORDER BY ASC (?cnName) ASC(?lgName)
}

}
ORDER BY ?cnName
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('cnName', 'Canada'), ('cmpn', 'Thomson Reuters'), ('lgName', 'corporation'), ('capitalization', '1')]
# [('cnName', 'Canada'), ('cmpn', 'Cineplex Entertainment'), ('lgName', 'public company'), ('capitalization', '1')]
# [('cnName', 'Canada'), ('cmpn', 'BlackBerry'), ('lgName', 'corporation')]
# [('cnName', 'Canada'), ('cmpn', 'Cineplex Entertainment'), ('lgName', 'public company')]
# [('cnName', 'United Kingdom'), ('cmpn', 'HSBC'), ('lgName', 'public limited company'), ('capitalization', '1')]
# [('cnName', 'United Kingdom'), ('cmpn', 'Lloyds Banking Group'), ('lgName', 'public limited company')]
# [('cnName', 'United States of America'), ('cmpn', 'Alphabet Inc.'), ('lgName', 'Delaware corporation'), ('capitalization', '1')]
# [('cnName', 'United States of America'), ('cmpn', 'Apple Inc.'), ('lgName', 'U.S. corporation'), ('capitalization', '1')]
# [('cnName', 'United States of America'), ('cmpn', 'Microsoft'), ('lgName', 'Washington corporation'), ('capitalization', '1')]
# [('cnName', 'United States of America'), ('cmpn', 'eBay'), ('lgName', 'corporation'), ('capitalization', '1')]
# [('cnName', 'United States of America'), ('cmpn', 'Amazon'), ('lgName', 'incorporation'), ('capitalization', '1')]
# [('cnName', 'United States of America'), ('cmpn', 'Berkshire Hathaway'), ('lgName', 'joint-stock company'), ('capitalization', '1')]
# [('cnName', 'United States of America'), ('cmpn', 'Uber Technology'), ('lgName', 'privately held company'), ('capitalization', '1')]
# [('cnName', 'United States of America'), ('cmpn', 'Microsoft'), ('lgName', 'public company'), ('capitalization', '1')]
# [('cnName', 'United States of America'), ('cmpn', 'Alphabet Inc.'), ('lgName', 'Delaware corporation')]
# [('cnName', 'United States of America'), ('cmpn', 'Northrop Grumman'), ('lgName', 'U.S. corporation')]
# [('cnName', 'United States of America'), ('cmpn', 'Microsoft'), ('lgName', 'Washington corporation')]
# [('cnName', 'United States of America'), ('cmpn', 'eBay'), ('lgName', 'corporation')]
# [('cnName', 'United States of America'), ('cmpn', 'Amazon'), ('lgName', 'incorporation')]
# [('cnName', 'United States of America'), ('cmpn', 'Cushman & Wakefield'), ('lgName', 'joint-stock company')]
# [('cnName', 'United States of America'), ('cmpn', 'Uber Technology'), ('lgName', 'privately held company')]
# [('cnName', 'United States of America'), ('cmpn', 'MEDLEY'), ('lgName', 'public company')]
# 22

# %% [raw]
# # DOES NOT work
# queryString = """
# {
# SELECT DISTINCT ?cnName ?cmpn ?lgName ?max_mcap
# WHERE {
#
# ?company wdt:P17 ?country .
# ?company wdt:P1454 ?legalForm .
#
# ?company wdt:P2226 ?marketcap1 .
#
# ?company <http://schema.org/name> ?cName1 .
# ?country <http://schema.org/name> ?cnName .
#
# ?legalForm <http://schema.org/name> ?lgName .
#
# FILTER (?marketcap1 = ?max_mcap)
#
# BIND (?cName1 AS ?cmpn)
#
# {
# SELECT DISTINCT ?country ?lgName (MAX(?marketcap) AS ?max_mcap)
# WHERE {
#
# ?company wdt:P17 ?country .
# ?company wdt:P31 wd:Q4830453  .
# ?company wdt:P1454 ?legalForm .
#
# ?company wdt:P2226 ?marketcap .
#
#
# ?legalForm <http://schema.org/name> ?lgName .
#
#
# FILTER (?country = wd:Q30 || ?country = wd:Q145 || ?country = wd:Q16)
#
#
# }
# GROUP BY (?lgName) (?country)
#
# }
#
# }
# ORDER BY ASC (?cnName) ASC(?lgName)
# }
# UNION
# {
# SELECT DISTINCT ?cnName ?cmpn ?lgName ?min_mcap
# WHERE {
#
# ?company wdt:P17 ?country .
# ?company wdt:P1454 ?legalForm .
#
# ?company wdt:P2226 ?marketcap2 .
#
# ?company <http://schema.org/name> ?cName2 .
# ?country <http://schema.org/name> ?cnName .
#
# ?legalForm <http://schema.org/name> ?lgName .
#
# FILTER (?marketcap2 = ?min_mcap)
#
# BIND (?cName2 AS ?cmpn)
#
# {
# SELECT DISTINCT ?country ?lgName (MIN(?marketcap) AS ?min_mcap)
# WHERE {
#
# ?company wdt:P17 ?country .
# ?company wdt:P31 wd:Q4830453  .
# ?company wdt:P1454 ?legalForm .
#
# ?company wdt:P2226 ?marketcap .
#
#
# ?legalForm <http://schema.org/name> ?lgName .
#
#
# FILTER (?country = wd:Q30 || ?country = wd:Q145 || ?country = wd:Q16)
#
#
# }
# GROUP BY (?lgName) (?country)
#
# }
#
# }
# ORDER BY ASC (?cnName) ASC(?lgName)
# }
# """
#
# print("Results")
# run_query(queryString)

# %% [markdown]
# ***5.3 Which business in each country owns more businesses in other countries?***
#
# It is a question similar to a previous one. I try to reuse that query modifying it a little bit

# %%
queryString = """

SELECT DISTINCT ?cnName ?cName COUNT(DISTINCT(?cName1)) AS ?numOfForeignComp
WHERE {

# ?company wdt:P17 ?country .
# ?company wdt:P31 wd:Q4830453  . 

# ?company wdt:P1830 ?obj5 . #owner of
# ?obj5 wdt:P17 ?country1.

# ?obj5 <http://schema.org/name> ?cName1 .

# ?company <http://schema.org/name> ?cName .
# ?country <http://schema.org/name> ?cnName .

# ?country1 <http://schema.org/name> ?cnName1 .

FILTER (?country1 != ?country)
FILTER (?country = wd:Q16)
} 
GROUP BY (?cnName) (?cName)
ORDER BY DESC(?numOfForeignComp)
LIMIT 1


"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('cnName', 'Canada'), ('cName', 'Barrick Gold'), ('numOfForeignComp', '5')]
# 1

# %%
queryString = """

SELECT DISTINCT  ?cnName ?cName ?numOfForeignComp WHERE {
    {
    
SELECT DISTINCT ?cnName ?cName COUNT(DISTINCT(?cName1)) AS ?numOfForeignComp
WHERE {

# ?company wdt:P17 ?country .
# ?company wdt:P31 wd:Q4830453  . 

# ?company wdt:P1830 ?obj5 . #owner of
# ?obj5 wdt:P17 ?country1.

# ?obj5 <http://schema.org/name> ?cName1 .

# ?company <http://schema.org/name> ?cName .
# ?country <http://schema.org/name> ?cnName .

# ?country1 <http://schema.org/name> ?cnName1 .

FILTER (?country1 != ?country)
FILTER (?country = wd:Q16)
} 
GROUP BY (?cnName) (?cName)
ORDER BY DESC(?numOfForeignComp)
LIMIT 1

    }
  UNION
   {
     SELECT DISTINCT ?cnName ?cName COUNT(DISTINCT(?cName1)) AS ?numOfForeignComp
WHERE {

# ?company wdt:P17 ?country .
# ?company wdt:P31 wd:Q4830453  . 

# ?company wdt:P1830 ?obj5 . #owner of
# ?obj5 wdt:P17 ?country1.

# ?obj5 <http://schema.org/name> ?cName1 .

# ?company <http://schema.org/name> ?cName .
# ?country <http://schema.org/name> ?cnName .

# ?country1 <http://schema.org/name> ?cnName1 .

FILTER (?country1 != ?country)
FILTER (?country = wd:Q30)
} 
GROUP BY (?cnName) (?cName)
ORDER BY DESC(?numOfForeignComp)
LIMIT 1
    }
UNION
{
     SELECT DISTINCT ?cnName ?cName COUNT(DISTINCT(?cName1)) AS ?numOfForeignComp
WHERE {

# ?company wdt:P17 ?country .
# ?company wdt:P31 wd:Q4830453  . 

# ?company wdt:P1830 ?obj5 . #owner of
# ?obj5 wdt:P17 ?country1.

# ?obj5 <http://schema.org/name> ?cName1 .

# ?company <http://schema.org/name> ?cName .
# ?country <http://schema.org/name> ?cnName .

# ?country1 <http://schema.org/name> ?cnName1 .

FILTER (?country1 != ?country)
FILTER (?country = wd:Q145)
} 
GROUP BY (?cnName) (?cName)
ORDER BY DESC(?numOfForeignComp)
LIMIT 1
    }
    }
ORDER BY ASC (?cnName)
    """

print("Results")
run_query(queryString)
# Out:
# Results
# [('cnName', 'Canada'), ('cName', 'Barrick Gold'), ('numOfForeignComp', '5')]
# [('cnName', 'United Kingdom'), ('cName', 'Liberty Global'), ('numOfForeignComp', '8')]
# [('cnName', 'United States of America'), ('cName', 'The Walt Disney Company'), ('numOfForeignComp', '59')]
# 3

# %% [markdown]
# **Answer 5.3**
#
# In Canada Barrick Gold owns 5 different business outside its country
#
# In UK Liberty Global owns 8 different business outside its country
#
# In USA The Walt Disney Company owns 59 different business outside its country

# %% [markdown]
# # General instructions
#
# The goal of the project is to materialize a set of **exploratory workloads** over a real-world, large-scale,  open-domain KG: [WikiData](https://www.wikidata.org/wiki/Wikidata:Main_Page)
#
# An exploratory workload  is composed by a set of queries, where each query is related to the information obtained previously.
#
# An exploratory workload starts with a usually vague, open ended question, and does not assume the person issuing the workload has a clear understanding of the data contained in the target database or its structure.
#
# Remeber that:
#
# 1. All the queries must run in the python notebook
# 2. You can use classes and properties only if you find them via a SPARQL query that must be present in the notebook
# 3. You do not delete useless queries. Keep everything that is synthatically valid
#
# ```
# ?p <http://schema.org/name> ?name .
# ```
#
#     is the BGP returning a human-readable name of a property or a class in Wikidata.

# %%
## SETUP used later

from SPARQLWrapper import SPARQLWrapper, JSON


prefixString = """
##-c6e02a72bf-##
PREFIX wd: <http://www.wikidata.org/entity/> 
PREFIX wdt: <http://www.wikidata.org/prop/direct/> 
PREFIX sc: <http://schema.org/>
"""

# select and construct queries
def run_query(queryString):
    to_run = prefixString + "\n" + queryString

    sparql = SPARQLWrapper("http://a256-gc1-02.srv.aau.dk:5820/sparql")
    sparql.setTimeout(300)
    sparql.setReturnFormat(JSON)
    sparql.setQuery(to_run)

    try :
       results = sparql.query()
       json_results = results.convert()
       if len(json_results['results']['bindings'])==0:
          print("Empty")
          return 0
    
       for bindings in json_results['results']['bindings']:
          print( [ (var, value['value'])  for var, value in bindings.items() ] )

       return len(json_results['results']['bindings'])

    except Exception as e :
        print("The operation failed", e)
    
# ASk queries
def run_ask_query(queryString):
    to_run = prefixString + "\n" + queryString

    sparql = SPARQLWrapper("http://a256-gc1-02.srv.aau.dk:5820/sparql")
    sparql.setTimeout(300)
    sparql.setReturnFormat(JSON)
    sparql.setQuery(to_run)

    try :
        return sparql.query().convert()

    except Exception as e :
        print("The operation failed", e)

# %% [markdown]
# # Movie Workflow Series ("Directors explorative search")
#
# Consider the following exploratory information need:
#
# > investigate the results concerning the common aspects between movies directed by Woody Allen or Quentin Tarantino. We want to know the people that worked for both directors with some numerical analyses, what are the differences in terms of budget for their movies, who won more Academy Awards.

# %% [markdown]
# ## Useful URIs for the current workflow
# The following are given:
#
# | IRI           | Description   | Role      |
# | -----------   | -----------   |-----------|
# | `wdt:P1647`   | subproperty   | predicate |
# | `wdt:P31`     | instance of   | predicate |
# | `wdt:P106`    | profession    | predicate |
# | `wdt:P279`    | subclass      | predicate |
# | `wdt:P27`     | nationality   | predicate |
# | `wdt:P106`     | profession   | predicate |
# | `wdt:P3342`     | Significant person       | predicate |
# | `wd:Q5`| Human       | node |
# | `wd:Q2526255`| Director       | node |
# | `wd:Q25089`| Woody Allen       | node |
# | `wd:Q3772`    | Quentin Tarantino      | node |

# %% [markdown]
# Also consider
#
# ```
# wd:Q25089 ?p ?obj .
# ```
#
# is the BGP to retrieve all **properties of Woody Allen**
#
#
# The workload should:
#
#
# 1. Identify the BGP for films
#
# 2. Identify the BGP for directors
#
# 3. Identify the BGP for workers in a films
#
# 4. Compare the workers amongst the films directed by the two directors
#
# 5. Return some numerical comparison between the two directors (e.g., how many workers in Tarantino's movies who also worked in Allen's films?, what is the film with the highest number of shared actors? Who is the most used actor by both the directors? etc. )
#
# 6. Is the maximum budget for a Tarantino's movie higher of the max budget of an Allen's movie?
#
# 7. Who has films with more nominations for Academy Awards and who won more Academy Awards (with his films not only personal awards).
#
#     7.1 Find the BGP for Academy Awards
#
#     7.2 Find the related subproperties
#
#     7.3 Find how they are related to the directors
#
#     7.4 Are there alternative queries to get the same result?

# %%
# start your workflow here

# %%
queryString = """
SELECT *
WHERE { 

wd:Q25089 ?p ?obj .
} 
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('p', 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), ('obj', 'http://wikiba.se/ontology#Item')]
# [('p', 'http://www.wikidata.org/prop/direct-normalized/P1006'), ('obj', 'http://data.bibliotheken.nl/id/thes/p06917654X')]
# [('p', 'http://www.wikidata.org/prop/direct-normalized/P1015'), ('obj', 'https://livedata.bibsys.no/authority/90085344')]
# [('p', 'http://www.wikidata.org/prop/direct-normalized/P1150'), ('obj', 'http://rvk.uni-regensburg.de/nt/HU+3027')]
# [('p', 'http://www.wikidata.org/prop/direct-normalized/P1741'), ('obj', 'http://data.beeldengeluid.nl/gtaa/76199')]
# [('p', 'http://www.wikidata.org/prop/direct-normalized/P214'), ('obj', 'http://viaf.org/viaf/59077912')]
# [('p', 'http://www.wikidata.org/prop/direct-normalized/P2163'), ('obj', 'http://id.worldcat.org/fast/1897483')]
# [('p', 'http://www.wikidata.org/prop/direct-normalized/P227'), ('obj', 'https://d-nb.info/gnd/118502077')]
# [('p', 'http://www.wikidata.org/prop/direct-normalized/P244'), ('obj', 'https://id.loc.gov/authorities/names/n79090269')]
# [('p', 'http://www.wikidata.org/prop/direct-normalized/P245'), ('obj', 'http://vocab.getty.edu/ulan/500273600')]
# [('p', 'http://www.wikidata.org/prop/direct-normalized/P268'), ('obj', 'http://data.bnf.fr/ark:/12148/cb11888505c#about')]
# [('p', 'http://www.wikidata.org/prop/direct-normalized/P269'), ('obj', 'http://www.idref.fr/027272699/id')]
# [('p', 'http://www.wikidata.org/prop/direct-normalized/P3348'), ('obj', 'http://data.nlg.gr/resource/authority/record68065')]
# [('p', 'http://www.wikidata.org/prop/direct-normalized/P349'), ('obj', 'http://id.ndl.go.jp/auth/ndlna/00431312')]
# [('p', 'http://www.wikidata.org/prop/direct-normalized/P4104'), ('obj', 'https://data.carnegiehall.org/names/49174/about')]
# [('p', 'http://www.wikidata.org/prop/direct-normalized/P434'), ('obj', 'http://musicbrainz.org/artist/f7476fda-687e-4d11-a02e-cfb88558867d')]
# [('p', 'http://www.wikidata.org/prop/direct-normalized/P5034'), ('obj', 'http://lod.nl.go.kr/resource/KAC199632561')]
# [('p', 'http://www.wikidata.org/prop/direct-normalized/P5063'), ('obj', 'http://globalwordnet.org/ili/i94283')]
# [('p', 'http://www.wikidata.org/prop/direct-normalized/P5361'), ('obj', 'https://bnb.data.bl.uk/doc/person/AllenWoody1935-')]
# [('p', 'http://www.wikidata.org/prop/direct-normalized/P5587'), ('obj', 'https://libris.kb.se/86lnpgfs38q0gs4')]
# [('p', 'http://www.wikidata.org/prop/direct-normalized/P5739'), ('obj', 'http://catalogo.pusc.it/auth/1506')]
# [('p', 'http://www.wikidata.org/prop/direct-normalized/P646'), ('obj', 'http://g.co/kg/m/081lh')]
# [('p', 'http://www.wikidata.org/prop/direct-normalized/P648'), ('obj', 'http://openlibrary.org/works/OL583968A')]
# [('p', 'http://www.wikidata.org/prop/direct-normalized/P8971'), ('obj', 'http://data.cinematheque.qc.ca/data/Person19445')]
# [('p', 'http://www.wikidata.org/prop/direct-normalized/P8980'), ('obj', 'https://urn.fi/URN:NBN:fi:au:finaf:000210730')]
# [('p', 'http://www.wikidata.org/prop/direct-normalized/P906'), ('obj', 'http://libris.kb.se/resource/auth/207594')]
# [('p', 'http://www.wikidata.org/prop/direct-normalized/P950'), ('obj', 'http://datos.bne.es/resource/XX1154054')]
# [('p', 'http://www.wikidata.org/prop/direct/P1003'), ('obj', '000004180')]
# [('p', 'http://www.wikidata.org/prop/direct/P1005'), ('obj', '821')]
# [('p', 'http://www.wikidata.org/prop/direct/P1006'), ('obj', '06917654X')]
# [('p', 'http://www.wikidata.org/prop/direct/P1015'), ('obj', '90085344')]
# [('p', 'http://www.wikidata.org/prop/direct/P103'), ('obj', 'http://www.wikidata.org/entity/Q1860')]
# [('p', 'http://www.wikidata.org/prop/direct/P106'), ('obj', 'http://www.wikidata.org/entity/Q10800557')]
# [('p', 'http://www.wikidata.org/prop/direct/P106'), ('obj', 'http://www.wikidata.org/entity/Q15981151')]
# [('p', 'http://www.wikidata.org/prop/direct/P106'), ('obj', 'http://www.wikidata.org/entity/Q18844224')]
# [('p', 'http://www.wikidata.org/prop/direct/P106'), ('obj', 'http://www.wikidata.org/entity/Q1930187')]
# [('p', 'http://www.wikidata.org/prop/direct/P106'), ('obj', 'http://www.wikidata.org/entity/Q214917')]
# [('p', 'http://www.wikidata.org/prop/direct/P106'), ('obj', 'http://www.wikidata.org/entity/Q245068')]
# [('p', 'http://www.wikidata.org/prop/direct/P106'), ('obj', 'http://www.wikidata.org/entity/Q2526255')]
# [('p', 'http://www.wikidata.org/prop/direct/P106'), ('obj', 'http://www.wikidata.org/entity/Q28389')]
# [('p', 'http://www.wikidata.org/prop/direct/P106'), ('obj', 'http://www.wikidata.org/entity/Q3282637')]
# [('p', 'http://www.wikidata.org/prop/direct/P106'), ('obj', 'http://www.wikidata.org/entity/Q36180')]
# [('p', 'http://www.wikidata.org/prop/direct/P106'), ('obj', 'http://www.wikidata.org/entity/Q36834')]
# [('p', 'http://www.wikidata.org/prop/direct/P106'), ('obj', 'http://www.wikidata.org/entity/Q482980')]
# [('p', 'http://www.wikidata.org/prop/direct/P106'), ('obj', 'http://www.wikidata.org/entity/Q639669')]
# [('p', 'http://www.wikidata.org/prop/direct/P106'), ('obj', 'http://www.wikidata.org/entity/Q948329')]
# [('p', 'http://www.wikidata.org/prop/direct/P106'), ('obj', 'http://www.wikidata.org/entity/Q118865')]
# [('p', 'http://www.wikidata.org/prop/direct/P108'), ('obj', 'http://www.wikidata.org/entity/Q599316')]
# [('p', 'http://www.wikidata.org/prop/direct/P109'), ('obj', 'http://commons.wikimedia.org/wiki/Special:FilePath/Woody%20Allen%20signature.svg')]
# [('p', 'http://www.wikidata.org/prop/direct/P1150'), ('obj', 'HU 3027')]
# [('p', 'http://www.wikidata.org/prop/direct/P1207'), ('obj', 'n93127346')]
# [('p', 'http://www.wikidata.org/prop/direct/P1220'), ('obj', '9226')]
# [('p', 'http://www.wikidata.org/prop/direct/P1233'), ('obj', '9650')]
# [('p', 'http://www.wikidata.org/prop/direct/P1263'), ('obj', '501/000022435')]
# [('p', 'http://www.wikidata.org/prop/direct/P1266'), ('obj', '357')]
# [('p', 'http://www.wikidata.org/prop/direct/P1273'), ('obj', 'a10038486')]
# [('p', 'http://www.wikidata.org/prop/direct/P1280'), ('obj', '8504163')]
# [('p', 'http://www.wikidata.org/prop/direct/P1283'), ('obj', 'http://www.wikidata.org/entity/Q2455835')]
# [('p', 'http://www.wikidata.org/prop/direct/P1284'), ('obj', '00000014021')]
# [('p', 'http://www.wikidata.org/prop/direct/P1296'), ('obj', '0002714')]
# [('p', 'http://www.wikidata.org/prop/direct/P1303'), ('obj', 'http://www.wikidata.org/entity/Q8343')]
# [('p', 'http://www.wikidata.org/prop/direct/P1309'), ('obj', 'vtls002611536')]
# [('p', 'http://www.wikidata.org/prop/direct/P1315'), ('obj', '906367')]
# [('p', 'http://www.wikidata.org/prop/direct/P1317'), ('obj', '2020-01-01T00:00:00Z')]
# [('p', 'http://www.wikidata.org/prop/direct/P1343'), ('obj', 'http://www.wikidata.org/entity/Q58488719')]
# [('p', 'http://www.wikidata.org/prop/direct/P1343'), ('obj', 'http://www.wikidata.org/entity/Q67311526')]
# [('p', 'http://www.wikidata.org/prop/direct/P1368'), ('obj', '000024233')]
# [('p', 'http://www.wikidata.org/prop/direct/P1375'), ('obj', '000056010')]
# [('p', 'http://www.wikidata.org/prop/direct/P138'), ('obj', 'http://www.wikidata.org/entity/Q349357')]
# [('p', 'http://www.wikidata.org/prop/direct/P1411'), ('obj', 'http://www.wikidata.org/entity/Q103360')]
# [('p', 'http://www.wikidata.org/prop/direct/P1411'), ('obj', 'http://www.wikidata.org/entity/Q41417')]
# [('p', 'http://www.wikidata.org/prop/direct/P1411'), ('obj', 'http://www.wikidata.org/entity/Q103916')]
# [('p', 'http://www.wikidata.org/prop/direct/P1411'), ('obj', 'http://www.wikidata.org/entity/Q1377772')]
# [('p', 'http://www.wikidata.org/prop/direct/P1412'), ('obj', 'http://www.wikidata.org/entity/Q1860')]
# [('p', 'http://www.wikidata.org/prop/direct/P1417'), ('obj', 'biography/Woody-Allen')]
# [('p', 'http://www.wikidata.org/prop/direct/P1455'), ('obj', 'http://www.wikidata.org/entity/Q16971520')]
# [('p', 'http://www.wikidata.org/prop/direct/P1477'), ('obj', 'Allan Stewart Konigsberg')]
# [('p', 'http://www.wikidata.org/prop/direct/P1559'), ('obj', 'Woody Allen')]
# [('p', 'http://www.wikidata.org/prop/direct/P1580'), ('obj', 'a1282847')]
# [('p', 'http://www.wikidata.org/prop/direct/P1607'), ('obj', '814159')]
# [('p', 'http://www.wikidata.org/prop/direct/P166'), ('obj', 'http://www.wikidata.org/entity/Q3404523')]
# [('p', 'http://www.wikidata.org/prop/direct/P166'), ('obj', 'http://www.wikidata.org/entity/Q31579')]
# [('p', 'http://www.wikidata.org/prop/direct/P166'), ('obj', 'http://www.wikidata.org/entity/Q3241784')]
# [('p', 'http://www.wikidata.org/prop/direct/P166'), ('obj', 'http://www.wikidata.org/entity/Q50616934')]
# [('p', 'http://www.wikidata.org/prop/direct/P166'), ('obj', 'http://www.wikidata.org/entity/Q3404587')]
# [('p', 'http://www.wikidata.org/prop/direct/P166'), ('obj', 'http://www.wikidata.org/entity/Q3822438')]
# [('p', 'http://www.wikidata.org/prop/direct/P166'), ('obj', 'http://www.wikidata.org/entity/Q103360')]
# [('p', 'http://www.wikidata.org/prop/direct/P166'), ('obj', 'http://www.wikidata.org/entity/Q13452531')]
# [('p', 'http://www.wikidata.org/prop/direct/P166'), ('obj', 'http://www.wikidata.org/entity/Q139184')]
# [('p', 'http://www.wikidata.org/prop/direct/P166'), ('obj', 'http://www.wikidata.org/entity/Q174389')]
# [('p', 'http://www.wikidata.org/prop/direct/P166'), ('obj', 'http://www.wikidata.org/entity/Q41417')]
# [('p', 'http://www.wikidata.org/prop/direct/P166'), ('obj', 'http://www.wikidata.org/entity/Q52382875')]
# [('p', 'http://www.wikidata.org/prop/direct/P166'), ('obj', 'http://www.wikidata.org/entity/Q708135')]
# [('p', 'http://www.wikidata.org/prop/direct/P166'), ('obj', 'http://www.wikidata.org/entity/Q787148')]
# [('p', 'http://www.wikidata.org/prop/direct/P166'), ('obj', 'http://www.wikidata.org/entity/Q908858')]
# [('p', 'http://www.wikidata.org/prop/direct/P166'), ('obj', 'http://www.wikidata.org/entity/Q1415017')]
# [('p', 'http://www.wikidata.org/prop/direct/P166'), ('obj', 'http://www.wikidata.org/entity/Q1789102')]
# [('p', 'http://www.wikidata.org/prop/direct/P166'), ('obj', 'http://www.wikidata.org/entity/Q768476')]
# [('p', 'http://www.wikidata.org/prop/direct/P166'), ('obj', 'http://www.wikidata.org/entity/Q2372386')]
# [('p', 'http://www.wikidata.org/prop/direct/P166'), ('obj', 'http://www.wikidata.org/entity/Q1111310')]
# [('p', 'http://www.wikidata.org/prop/direct/P166'), ('obj', 'http://www.wikidata.org/entity/Q1170507')]
# [('p', 'http://www.wikidata.org/prop/direct/P166'), ('obj', 'http://www.wikidata.org/entity/Q3319305')]
# [('p', 'http://www.wikidata.org/prop/direct/P166'), ('obj', 'http://www.wikidata.org/entity/Q787131')]
# [('p', 'http://www.wikidata.org/prop/direct/P166'), ('obj', 'http://www.wikidata.org/entity/Q41375')]
# [('p', 'http://www.wikidata.org/prop/direct/P166'), ('obj', 'http://www.wikidata.org/entity/Q849124')]
# [('p', 'http://www.wikidata.org/prop/direct/P166'), ('obj', 'http://www.wikidata.org/entity/Q19339')]
# [('p', 'http://www.wikidata.org/prop/direct/P166'), ('obj', 'http://www.wikidata.org/entity/Q670282')]
# [('p', 'http://www.wikidata.org/prop/direct/P166'), ('obj', 'http://www.wikidata.org/entity/Q889842')]
# [('p', 'http://www.wikidata.org/prop/direct/P166'), ('obj', 'http://www.wikidata.org/entity/Q20970213')]
# [('p', 'http://www.wikidata.org/prop/direct/P166'), ('obj', 'http://www.wikidata.org/entity/Q2418096')]
# [('p', 'http://www.wikidata.org/prop/direct/P166'), ('obj', 'http://www.wikidata.org/entity/Q6351683')]
# [('p', 'http://www.wikidata.org/prop/direct/P166'), ('obj', 'http://www.wikidata.org/entity/Q6351674')]
# [('p', 'http://www.wikidata.org/prop/direct/P1695'), ('obj', 'A11854273')]
# [('p', 'http://www.wikidata.org/prop/direct/P172'), ('obj', 'http://www.wikidata.org/entity/Q678551')]
# [('p', 'http://www.wikidata.org/prop/direct/P1728'), ('obj', 'mn0000678950')]
# [('p', 'http://www.wikidata.org/prop/direct/P1741'), ('obj', '76199')]
# [('p', 'http://www.wikidata.org/prop/direct/P18'), ('obj', 'http://commons.wikimedia.org/wiki/Special:FilePath/Woody%20Allen%20Cannes%202011.jpg')]
# [('p', 'http://www.wikidata.org/prop/direct/P1816'), ('obj', 'mp64909')]
# [('p', 'http://www.wikidata.org/prop/direct/P1819'), ('obj', 'I00444594')]
# [('p', 'http://www.wikidata.org/prop/direct/P19'), ('obj', 'http://www.wikidata.org/entity/Q18426')]
# [('p', 'http://www.wikidata.org/prop/direct/P1953'), ('obj', '694549')]
# [('p', 'http://www.wikidata.org/prop/direct/P1969'), ('obj', '13607')]
# [('p', 'http://www.wikidata.org/prop/direct/P1977'), ('obj', '40527')]
# [('p', 'http://www.wikidata.org/prop/direct/P2019'), ('obj', 'p79388')]
# [('p', 'http://www.wikidata.org/prop/direct/P2031'), ('obj', '1950-01-01T00:00:00Z')]
# [('p', 'http://www.wikidata.org/prop/direct/P21'), ('obj', 'http://www.wikidata.org/entity/Q6581097')]
# [('p', 'http://www.wikidata.org/prop/direct/P213'), ('obj', '0000 0001 2134 7589')]
# [('p', 'http://www.wikidata.org/prop/direct/P214'), ('obj', '59077912')]
# [('p', 'http://www.wikidata.org/prop/direct/P2163'), ('obj', '1897483')]
# [('p', 'http://www.wikidata.org/prop/direct/P2168'), ('obj', '72675')]
# [('p', 'http://www.wikidata.org/prop/direct/P2174'), ('obj', '32175')]
# [('p', 'http://www.wikidata.org/prop/direct/P2188'), ('obj', '29913')]
# [('p', 'http://www.wikidata.org/prop/direct/P2190'), ('obj', 'woodyallen')]
# [('p', 'http://www.wikidata.org/prop/direct/P2191'), ('obj', '10079')]
# [('p', 'http://www.wikidata.org/prop/direct/P22'), ('obj', 'http://www.wikidata.org/entity/Q108223439')]
# [('p', 'http://www.wikidata.org/prop/direct/P227'), ('obj', '118502077')]
# [('p', 'http://www.wikidata.org/prop/direct/P2387'), ('obj', '100324')]
# [('p', 'http://www.wikidata.org/prop/direct/P2435'), ('obj', '1667')]
# [('p', 'http://www.wikidata.org/prop/direct/P244'), ('obj', 'n79090269')]
# [('p', 'http://www.wikidata.org/prop/direct/P245'), ('obj', '500273600')]
# [('p', 'http://www.wikidata.org/prop/direct/P2469'), ('obj', '2303')]
# [('p', 'http://www.wikidata.org/prop/direct/P25'), ('obj', 'http://www.wikidata.org/entity/Q108223445')]
# [('p', 'http://www.wikidata.org/prop/direct/P2519'), ('obj', '610')]
# [('p', 'http://www.wikidata.org/prop/direct/P26'), ('obj', 'http://www.wikidata.org/entity/Q1140914')]
# [('p', 'http://www.wikidata.org/prop/direct/P2600'), ('obj', '6000000006823605220')]
# [('p', 'http://www.wikidata.org/prop/direct/P2604'), ('obj', '5890')]
# [('p', 'http://www.wikidata.org/prop/direct/P2605'), ('obj', '346')]
# [('p', 'http://www.wikidata.org/prop/direct/P2626'), ('obj', '6776')]
# [('p', 'http://www.wikidata.org/prop/direct/P2638'), ('obj', 'people/woody-allen')]
# [('p', 'http://www.wikidata.org/prop/direct/P264'), ('obj', 'http://www.wikidata.org/entity/Q193023')]
# [('p', 'http://www.wikidata.org/prop/direct/P268'), ('obj', '11888505c')]
# [('p', 'http://www.wikidata.org/prop/direct/P2688'), ('obj', 'woodallen')]
# [('p', 'http://www.wikidata.org/prop/direct/P269'), ('obj', '027272699')]
# [('p', 'http://www.wikidata.org/prop/direct/P27'), ('obj', 'http://www.wikidata.org/entity/Q30')]
# [('p', 'http://www.wikidata.org/prop/direct/P271'), ('obj', 'DA01341288')]
# [('p', 'http://www.wikidata.org/prop/direct/P2734'), ('obj', 'AllenWoody')]
# [('p', 'http://www.wikidata.org/prop/direct/P2924'), ('obj', '3261226')]
# [('p', 'http://www.wikidata.org/prop/direct/P2963'), ('obj', '10356')]
# [('p', 'http://www.wikidata.org/prop/direct/P3056'), ('obj', '2615')]
# [('p', 'http://www.wikidata.org/prop/direct/P3065'), ('obj', '02-A002919919')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('obj', 'http://www.wikidata.org/entity/Q5')]
# [('p', 'http://www.wikidata.org/prop/direct/P3106'), ('obj', 'film/woodyallen')]
# [('p', 'http://www.wikidata.org/prop/direct/P3136'), ('obj', '1148580')]
# [('p', 'http://www.wikidata.org/prop/direct/P3142'), ('obj', 'n0002881')]
# [('p', 'http://www.wikidata.org/prop/direct/P3219'), ('obj', 'woody-allen')]
# [('p', 'http://www.wikidata.org/prop/direct/P3222'), ('obj', 'woody-allen')]
# [('p', 'http://www.wikidata.org/prop/direct/P3280'), ('obj', '0000356006')]
# [('p', 'http://www.wikidata.org/prop/direct/P3305'), ('obj', '4624')]
# [('p', 'http://www.wikidata.org/prop/direct/P3348'), ('obj', '68065')]
# [('p', 'http://www.wikidata.org/prop/direct/P3373'), ('obj', 'http://www.wikidata.org/entity/Q3831197')]
# [('p', 'http://www.wikidata.org/prop/direct/P3417'), ('obj', 'Woody-Allen-Playwriter')]
# [('p', 'http://www.wikidata.org/prop/direct/P3417'), ('obj', 'Woody-Allen-actor-director')]
# [('p', 'http://www.wikidata.org/prop/direct/P3430'), ('obj', 'w6ps26gg')]
# [('p', 'http://www.wikidata.org/prop/direct/P345'), ('obj', 'nm0000095')]
# [('p', 'http://www.wikidata.org/prop/direct/P3478'), ('obj', '366139')]
# [('p', 'http://www.wikidata.org/prop/direct/P3479'), ('obj', 'e783d9b068fb98ff68b525b7f41199205f51a071')]
# [('p', 'http://www.wikidata.org/prop/direct/P349'), ('obj', '00431312')]
# [('p', 'http://www.wikidata.org/prop/direct/P3553'), ('obj', '19634130')]
# [('p', 'http://www.wikidata.org/prop/direct/P3569'), ('obj', 'film/woody-allen')]
# [('p', 'http://www.wikidata.org/prop/direct/P3630'), ('obj', '2640')]
# [('p', 'http://www.wikidata.org/prop/direct/P373'), ('obj', 'Woody Allen')]
# [('p', 'http://www.wikidata.org/prop/direct/P3762'), ('obj', '124168')]
# [('p', 'http://www.wikidata.org/prop/direct/P3782'), ('obj', 'woody-allen')]
# [('p', 'http://www.wikidata.org/prop/direct/P3788'), ('obj', '000027166')]
# [('p', 'http://www.wikidata.org/prop/direct/P3846'), ('obj', '87097969361900')]
# [('p', 'http://www.wikidata.org/prop/direct/P396'), ('obj', 'IT\\ICCU\\CFIV\\000724')]
# [('p', 'http://www.wikidata.org/prop/direct/P3987'), ('obj', '456917')]
# [('p', 'http://www.wikidata.org/prop/direct/P40'), ('obj', 'http://www.wikidata.org/entity/Q22673707')]
# [('p', 'http://www.wikidata.org/prop/direct/P40'), ('obj', 'http://www.wikidata.org/entity/Q22673708')]
# [('p', 'http://www.wikidata.org/prop/direct/P40'), ('obj', 'http://www.wikidata.org/entity/Q100135417')]
# [('p', 'http://www.wikidata.org/prop/direct/P40'), ('obj', 'http://www.wikidata.org/entity/Q16217493')]
# [('p', 'http://www.wikidata.org/prop/direct/P40'), ('obj', 'http://www.wikidata.org/entity/Q7365461')]
# [('p', 'http://www.wikidata.org/prop/direct/P409'), ('obj', '35308903')]
# [('p', 'http://www.wikidata.org/prop/direct/P4104'), ('obj', '49174')]
# [('p', 'http://www.wikidata.org/prop/direct/P4208'), ('obj', 'woody-allen')]
# [('p', 'http://www.wikidata.org/prop/direct/P4293'), ('obj', 'pe/000378')]
# [('p', 'http://www.wikidata.org/prop/direct/P434'), ('obj', 'f7476fda-687e-4d11-a02e-cfb88558867d')]
# [('p', 'http://www.wikidata.org/prop/direct/P4342'), ('obj', 'Woody_Allen')]
# [('p', 'http://www.wikidata.org/prop/direct/P4456'), ('obj', '6537')]
# [('p', 'http://www.wikidata.org/prop/direct/P451'), ('obj', 'http://www.wikidata.org/entity/Q102642')]
# [('p', 'http://www.wikidata.org/prop/direct/P451'), ('obj', 'http://www.wikidata.org/entity/Q202725')]
# [('p', 'http://www.wikidata.org/prop/direct/P4619'), ('obj', '000568283')]
# [('p', 'http://www.wikidata.org/prop/direct/P463'), ('obj', 'http://www.wikidata.org/entity/Q463303')]
# [('p', 'http://www.wikidata.org/prop/direct/P4638'), ('obj', 'p25315.htm#i253147')]
# [('p', 'http://www.wikidata.org/prop/direct/P4657'), ('obj', '4010401')]
# [('p', 'http://www.wikidata.org/prop/direct/P4985'), ('obj', '1243')]
# [('p', 'http://www.wikidata.org/prop/direct/P5019'), ('obj', 'allen-woody')]
# [('p', 'http://www.wikidata.org/prop/direct/P5033'), ('obj', '1')]
# [('p', 'http://www.wikidata.org/prop/direct/P5034'), ('obj', 'KAC199632561')]
# [('p', 'http://www.wikidata.org/prop/direct/P5063'), ('obj', 'i94283')]
# [('p', 'http://www.wikidata.org/prop/direct/P5068'), ('obj', '1878513')]
# [('p', 'http://www.wikidata.org/prop/direct/P5121'), ('obj', '16524')]
# [('p', 'http://www.wikidata.org/prop/direct/P5284'), ('obj', '1054430')]
# [('p', 'http://www.wikidata.org/prop/direct/P5312'), ('obj', '232')]
# [('p', 'http://www.wikidata.org/prop/direct/P5361'), ('obj', 'AllenWoody1935-')]
# [('p', 'http://www.wikidata.org/prop/direct/P5414'), ('obj', '1550')]
# [('p', 'http://www.wikidata.org/prop/direct/P5419'), ('obj', 'woody-allen')]
# [('p', 'http://www.wikidata.org/prop/direct/P5421'), ('obj', '88319')]
# [('p', 'http://www.wikidata.org/prop/direct/P5491'), ('obj', '14509')]
# [('p', 'http://www.wikidata.org/prop/direct/P5534'), ('obj', '1243')]
# [('p', 'http://www.wikidata.org/prop/direct/P5587'), ('obj', '86lnpgfs38q0gs4')]
# [('p', 'http://www.wikidata.org/prop/direct/P5617'), ('obj', 'woody-allen-75')]
# [('p', 'http://www.wikidata.org/prop/direct/P569'), ('obj', '1935-12-01T00:00:00Z')]
# [('p', 'http://www.wikidata.org/prop/direct/P5739'), ('obj', '1506')]
# [('p', 'http://www.wikidata.org/prop/direct/P5882'), ('obj', 'M00000095203')]
# [('p', 'http://www.wikidata.org/prop/direct/P5905'), ('obj', '4005-66810')]
# [('p', 'http://www.wikidata.org/prop/direct/P5905'), ('obj', '4040-114447')]
# [('p', 'http://www.wikidata.org/prop/direct/P6058'), ('obj', 'personnage/wd/104892')]
# [('p', 'http://www.wikidata.org/prop/direct/P6150'), ('obj', '3610')]
# [('p', 'http://www.wikidata.org/prop/direct/P6181'), ('obj', 'allen-woody')]
# [('p', 'http://www.wikidata.org/prop/direct/P6262'), ('obj', 'disney:Woody_Allen')]
# [('p', 'http://www.wikidata.org/prop/direct/P6379'), ('obj', 'http://www.wikidata.org/entity/Q188740')]
# [('p', 'http://www.wikidata.org/prop/direct/P6394'), ('obj', 'a1118324x')]
# [('p', 'http://www.wikidata.org/prop/direct/P646'), ('obj', '/m/081lh')]
# [('p', 'http://www.wikidata.org/prop/direct/P648'), ('obj', 'OL583968A')]
# [('p', 'http://www.wikidata.org/prop/direct/P6656'), ('obj', '76252')]
# [('p', 'http://www.wikidata.org/prop/direct/P6706'), ('obj', 'Allen,+Woody')]
# [('p', 'http://www.wikidata.org/prop/direct/P6844'), ('obj', '29368')]
# [('p', 'http://www.wikidata.org/prop/direct/P6870'), ('obj', '60517')]
# [('p', 'http://www.wikidata.org/prop/direct/P69'), ('obj', 'http://www.wikidata.org/entity/Q797078')]
# [('p', 'http://www.wikidata.org/prop/direct/P69'), ('obj', 'http://www.wikidata.org/entity/Q10749664')]
# [('p', 'http://www.wikidata.org/prop/direct/P691'), ('obj', 'jn19981000084')]
# [('p', 'http://www.wikidata.org/prop/direct/P7029'), ('obj', '7715539')]
# [('p', 'http://www.wikidata.org/prop/direct/P7084'), ('obj', 'http://www.wikidata.org/entity/Q7778126')]
# [('p', 'http://www.wikidata.org/prop/direct/P7214'), ('obj', '2978')]
# [('p', 'http://www.wikidata.org/prop/direct/P7293'), ('obj', '9810671732905606')]
# [('p', 'http://www.wikidata.org/prop/direct/P734'), ('obj', 'http://www.wikidata.org/entity/Q2648323')]
# [('p', 'http://www.wikidata.org/prop/direct/P735'), ('obj', 'http://www.wikidata.org/entity/Q19961034')]
# [('p', 'http://www.wikidata.org/prop/direct/P7369'), ('obj', '000244652')]
# [('p', 'http://www.wikidata.org/prop/direct/P7400'), ('obj', 'allenwoody')]
# [('p', 'http://www.wikidata.org/prop/direct/P7699'), ('obj', 'LNB:V*293653;=BO')]
# [('p', 'http://www.wikidata.org/prop/direct/P7700'), ('obj', 'vtls011691200')]
# [('p', 'http://www.wikidata.org/prop/direct/P7763'), ('obj', 'http://www.wikidata.org/entity/Q73555012')]
# [('p', 'http://www.wikidata.org/prop/direct/P7803'), ('obj', '8386')]
# [('p', 'http://www.wikidata.org/prop/direct/P7818'), ('obj', 'Woody_Allen')]
# [('p', 'http://www.wikidata.org/prop/direct/P7859'), ('obj', 'lccn-n79090269')]
# [('p', 'http://www.wikidata.org/prop/direct/P7865'), ('obj', '95a5yja38danygu695b5yc1g60vk4d0')]
# [('p', 'http://www.wikidata.org/prop/direct/P7902'), ('obj', '118502077')]
# [('p', 'http://www.wikidata.org/prop/direct/P7929'), ('obj', 'p=allen+stewart;n=konigsberg')]
# [('p', 'http://www.wikidata.org/prop/direct/P800'), ('obj', 'http://www.wikidata.org/entity/Q206124')]
# [('p', 'http://www.wikidata.org/prop/direct/P800'), ('obj', 'http://www.wikidata.org/entity/Q971865')]
# [('p', 'http://www.wikidata.org/prop/direct/P800'), ('obj', 'http://www.wikidata.org/entity/Q1004531')]
# [('p', 'http://www.wikidata.org/prop/direct/P800'), ('obj', 'http://www.wikidata.org/entity/Q1354109')]
# [('p', 'http://www.wikidata.org/prop/direct/P800'), ('obj', 'http://www.wikidata.org/entity/Q729026')]
# [('p', 'http://www.wikidata.org/prop/direct/P800'), ('obj', 'http://www.wikidata.org/entity/Q733677')]
# [('p', 'http://www.wikidata.org/prop/direct/P800'), ('obj', 'http://www.wikidata.org/entity/Q740143')]
# [('p', 'http://www.wikidata.org/prop/direct/P800'), ('obj', 'http://www.wikidata.org/entity/Q806092')]
# [('p', 'http://www.wikidata.org/prop/direct/P800'), ('obj', 'http://www.wikidata.org/entity/Q1321004')]
# [('p', 'http://www.wikidata.org/prop/direct/P800'), ('obj', 'http://www.wikidata.org/entity/Q14511869')]
# [('p', 'http://www.wikidata.org/prop/direct/P800'), ('obj', 'http://www.wikidata.org/entity/Q614009')]
# [('p', 'http://www.wikidata.org/prop/direct/P800'), ('obj', 'http://www.wikidata.org/entity/Q187423')]
# [('p', 'http://www.wikidata.org/prop/direct/P800'), ('obj', 'http://www.wikidata.org/entity/Q27703144')]
# [('p', 'http://www.wikidata.org/prop/direct/P800'), ('obj', 'http://www.wikidata.org/entity/Q786585')]
# [('p', 'http://www.wikidata.org/prop/direct/P800'), ('obj', 'http://www.wikidata.org/entity/Q1052826')]
# [('p', 'http://www.wikidata.org/prop/direct/P800'), ('obj', 'http://www.wikidata.org/entity/Q1218888')]
# [('p', 'http://www.wikidata.org/prop/direct/P800'), ('obj', 'http://www.wikidata.org/entity/Q181555')]
# [('p', 'http://www.wikidata.org/prop/direct/P800'), ('obj', 'http://www.wikidata.org/entity/Q682002')]
# [('p', 'http://www.wikidata.org/prop/direct/P800'), ('obj', 'http://www.wikidata.org/entity/Q653518')]
# [('p', 'http://www.wikidata.org/prop/direct/P800'), ('obj', 'http://www.wikidata.org/entity/Q977372')]
# [('p', 'http://www.wikidata.org/prop/direct/P800'), ('obj', 'http://www.wikidata.org/entity/Q750003')]
# [('p', 'http://www.wikidata.org/prop/direct/P800'), ('obj', 'http://www.wikidata.org/entity/Q610163')]
# [('p', 'http://www.wikidata.org/prop/direct/P800'), ('obj', 'http://www.wikidata.org/entity/Q910523')]
# [('p', 'http://www.wikidata.org/prop/direct/P800'), ('obj', 'http://www.wikidata.org/entity/Q1133277')]
# [('p', 'http://www.wikidata.org/prop/direct/P800'), ('obj', 'http://www.wikidata.org/entity/Q1146315')]
# [('p', 'http://www.wikidata.org/prop/direct/P800'), ('obj', 'http://www.wikidata.org/entity/Q1354121')]
# [('p', 'http://www.wikidata.org/prop/direct/P800'), ('obj', 'http://www.wikidata.org/entity/Q2907178')]
# [('p', 'http://www.wikidata.org/prop/direct/P800'), ('obj', 'http://www.wikidata.org/entity/Q18844733')]
# [('p', 'http://www.wikidata.org/prop/direct/P800'), ('obj', 'http://www.wikidata.org/entity/Q731310')]
# [('p', 'http://www.wikidata.org/prop/direct/P800'), ('obj', 'http://www.wikidata.org/entity/Q833530')]
# [('p', 'http://www.wikidata.org/prop/direct/P800'), ('obj', 'http://www.wikidata.org/entity/Q499697')]
# [('p', 'http://www.wikidata.org/prop/direct/P800'), ('obj', 'http://www.wikidata.org/entity/Q912729')]
# [('p', 'http://www.wikidata.org/prop/direct/P800'), ('obj', 'http://www.wikidata.org/entity/Q1770003')]
# [('p', 'http://www.wikidata.org/prop/direct/P800'), ('obj', 'http://www.wikidata.org/entity/Q692208')]
# [('p', 'http://www.wikidata.org/prop/direct/P800'), ('obj', 'http://www.wikidata.org/entity/Q17417520')]
# [('p', 'http://www.wikidata.org/prop/direct/P800'), ('obj', 'http://www.wikidata.org/entity/Q29658')]
# [('p', 'http://www.wikidata.org/prop/direct/P800'), ('obj', 'http://www.wikidata.org/entity/Q20950014')]
# [('p', 'http://www.wikidata.org/prop/direct/P800'), ('obj', 'http://www.wikidata.org/entity/Q1306629')]
# [('p', 'http://www.wikidata.org/prop/direct/P800'), ('obj', 'http://www.wikidata.org/entity/Q541185')]
# [('p', 'http://www.wikidata.org/prop/direct/P800'), ('obj', 'http://www.wikidata.org/entity/Q685109')]
# [('p', 'http://www.wikidata.org/prop/direct/P800'), ('obj', 'http://www.wikidata.org/entity/Q42307699')]
# [('p', 'http://www.wikidata.org/prop/direct/P800'), ('obj', 'http://www.wikidata.org/entity/Q1334572')]
# [('p', 'http://www.wikidata.org/prop/direct/P800'), ('obj', 'http://www.wikidata.org/entity/Q212123')]
# [('p', 'http://www.wikidata.org/prop/direct/P800'), ('obj', 'http://www.wikidata.org/entity/Q233464')]
# [('p', 'http://www.wikidata.org/prop/direct/P800'), ('obj', 'http://www.wikidata.org/entity/Q335508')]
# [('p', 'http://www.wikidata.org/prop/direct/P800'), ('obj', 'http://www.wikidata.org/entity/Q551762')]
# [('p', 'http://www.wikidata.org/prop/direct/P800'), ('obj', 'http://www.wikidata.org/entity/Q582021')]
# [('p', 'http://www.wikidata.org/prop/direct/P800'), ('obj', 'http://www.wikidata.org/entity/Q845057')]
# [('p', 'http://www.wikidata.org/prop/direct/P800'), ('obj', 'http://www.wikidata.org/entity/Q961403')]
# [('p', 'http://www.wikidata.org/prop/direct/P8094'), ('obj', 'allenw')]
# [('p', 'http://www.wikidata.org/prop/direct/P8179'), ('obj', 'ncf10388597')]
# [('p', 'http://www.wikidata.org/prop/direct/P8189'), ('obj', '987007257668105171')]
# [('p', 'http://www.wikidata.org/prop/direct/P8349'), ('obj', '8057')]
# [('p', 'http://www.wikidata.org/prop/direct/P8385'), ('obj', '856')]
# [('p', 'http://www.wikidata.org/prop/direct/P856'), ('obj', 'https://www.woodyallen.com/')]
# [('p', 'http://www.wikidata.org/prop/direct/P8625'), ('obj', 'http://www.wikidata.org/entity/Q16971520')]
# [('p', 'http://www.wikidata.org/prop/direct/P866'), ('obj', 'woody-allen')]
# [('p', 'http://www.wikidata.org/prop/direct/P8796'), ('obj', '29')]
# [('p', 'http://www.wikidata.org/prop/direct/P8814'), ('obj', '10834557-n')]
# [('p', 'http://www.wikidata.org/prop/direct/P8971'), ('obj', '19445')]
# [('p', 'http://www.wikidata.org/prop/direct/P8974'), ('obj', 'a/9bbb4628-d558-4437-8049-a2592f7dabfd')]
# [('p', 'http://www.wikidata.org/prop/direct/P8980'), ('obj', '000210730')]
# [('p', 'http://www.wikidata.org/prop/direct/P9037'), ('obj', 'f8e1257a-2f33-4eb0-844f-fe171f2f1634')]
# [('p', 'http://www.wikidata.org/prop/direct/P906'), ('obj', '207594')]
# [('p', 'http://www.wikidata.org/prop/direct/P910'), ('obj', 'http://www.wikidata.org/entity/Q7370834')]
# [('p', 'http://www.wikidata.org/prop/direct/P9141'), ('obj', '599')]
# [('p', 'http://www.wikidata.org/prop/direct/P935'), ('obj', 'Woody Allen')]
# [('p', 'http://www.wikidata.org/prop/direct/P949'), ('obj', '000008793')]
# [('p', 'http://www.wikidata.org/prop/direct/P950'), ('obj', 'XX1154054')]
# [('p', 'http://www.wikidata.org/prop/direct/P9743'), ('obj', '107aIW1Qlk')]
# [('p', 'http://www.wikidata.org/prop/direct/P9807'), ('obj', '172827')]
# [('p', 'http://schema.org/name'), ('obj', 'Woody Allen')]
# [('p', 'http://www.wikidata.org/prop/direct/P3144'), ('obj', '3232487')]
# [('p', 'http://www.wikidata.org/prop/direct/P4283'), ('obj', '46')]
# [('p', 'http://www.wikidata.org/prop/direct/P8929'), ('obj', 'http://www.wikidata.org/entity/Q288928')]
# 334

# %% [markdown]
# ## Task 1

# %%
# get predicates from Woody Allen

queryString = """
SELECT DISTINCT ?p ?plbl
WHERE { 

wd:Q25089 ?p ?obj .

# ?p <http://schema.org/name> ?plbl

FILTER (!CONTAINS (?plbl, "ID") && !CONTAINS (?plbl, "username") && !CONTAINS (?plbl, "code"))

} 
ORDER BY ?plbl
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P373'), ('plbl', 'Commons category')]
# [('p', 'http://www.wikidata.org/prop/direct/P935'), ('plbl', 'Commons gallery')]
# [('p', 'http://www.wikidata.org/prop/direct/P213'), ('plbl', 'ISNI')]
# [('p', 'http://www.wikidata.org/prop/direct/P5587'), ('plbl', 'Libris-URI')]
# [('p', 'http://www.wikidata.org/prop/direct/P1150'), ('plbl', 'Regensburg Classification')]
# [('p', 'http://www.wikidata.org/prop/direct/P166'), ('plbl', 'award received')]
# [('p', 'http://www.wikidata.org/prop/direct/P8625'), ('plbl', 'bibliography')]
# [('p', 'http://www.wikidata.org/prop/direct/P1477'), ('plbl', 'birth name')]
# [('p', 'http://www.wikidata.org/prop/direct/P40'), ('plbl', 'child')]
# [('p', 'http://www.wikidata.org/prop/direct/P7763'), ('plbl', 'copyright status as a creator')]
# [('p', 'http://www.wikidata.org/prop/direct/P27'), ('plbl', 'country of citizenship')]
# [('p', 'http://www.wikidata.org/prop/direct/P569'), ('plbl', 'date of birth')]
# [('p', 'http://www.wikidata.org/prop/direct/P1343'), ('plbl', 'described by source')]
# [('p', 'http://www.wikidata.org/prop/direct/P69'), ('plbl', 'educated at')]
# [('p', 'http://www.wikidata.org/prop/direct/P108'), ('plbl', 'employer')]
# [('p', 'http://www.wikidata.org/prop/direct/P172'), ('plbl', 'ethnic group')]
# [('p', 'http://www.wikidata.org/prop/direct/P734'), ('plbl', 'family name')]
# [('p', 'http://www.wikidata.org/prop/direct/P22'), ('plbl', 'father')]
# [('p', 'http://www.wikidata.org/prop/direct/P1283'), ('plbl', 'filmography')]
# [('p', 'http://www.wikidata.org/prop/direct/P1317'), ('plbl', 'floruit')]
# [('p', 'http://www.wikidata.org/prop/direct/P735'), ('plbl', 'given name')]
# [('p', 'http://www.wikidata.org/prop/direct/P6379'), ('plbl', 'has works in the collection')]
# [('p', 'http://www.wikidata.org/prop/direct/P18'), ('plbl', 'image')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('plbl', 'instance of')]
# [('p', 'http://www.wikidata.org/prop/direct/P1303'), ('plbl', 'instrument')]
# [('p', 'http://www.wikidata.org/prop/direct/P1412'), ('plbl', 'languages spoken, written or signed')]
# [('p', 'http://www.wikidata.org/prop/direct/P1455'), ('plbl', 'list of works')]
# [('p', 'http://www.wikidata.org/prop/direct/P463'), ('plbl', 'member of')]
# [('p', 'http://www.wikidata.org/prop/direct/P25'), ('plbl', 'mother')]
# [('p', 'http://www.wikidata.org/prop/direct/P1559'), ('plbl', 'name in native language')]
# [('p', 'http://www.wikidata.org/prop/direct/P138'), ('plbl', 'named after')]
# [('p', 'http://www.wikidata.org/prop/direct/P103'), ('plbl', 'native language')]
# [('p', 'http://www.wikidata.org/prop/direct/P1411'), ('plbl', 'nominated for')]
# [('p', 'http://www.wikidata.org/prop/direct/P800'), ('plbl', 'notable work')]
# [('p', 'http://www.wikidata.org/prop/direct/P106'), ('plbl', 'occupation')]
# [('p', 'http://www.wikidata.org/prop/direct/P856'), ('plbl', 'official website')]
# [('p', 'http://www.wikidata.org/prop/direct/P19'), ('plbl', 'place of birth')]
# [('p', 'http://www.wikidata.org/prop/direct/P264'), ('plbl', 'record label')]
# [('p', 'http://www.wikidata.org/prop/direct/P7084'), ('plbl', 'related category')]
# [('p', 'http://www.wikidata.org/prop/direct/P8929'), ('plbl', 'religion or world view')]
# [('p', 'http://www.wikidata.org/prop/direct/P21'), ('plbl', 'sex or gender')]
# [('p', 'http://www.wikidata.org/prop/direct/P3373'), ('plbl', 'sibling')]
# [('p', 'http://www.wikidata.org/prop/direct/P109'), ('plbl', 'signature')]
# [('p', 'http://www.wikidata.org/prop/direct/P26'), ('plbl', 'spouse')]
# [('p', 'http://www.wikidata.org/prop/direct/P910'), ('plbl', "topic's main category")]
# [('p', 'http://www.wikidata.org/prop/direct/P451'), ('plbl', 'unmarried partner')]
# [('p', 'http://www.wikidata.org/prop/direct/P2031'), ('plbl', 'work period (start)')]
# 47

# %%
# get filmography of Woody Allen

queryString = """
SELECT DISTINCT ?o ?olbl ?o2 ?o2lbl
WHERE { 

wd:Q25089 wdt:P1283 ?o .

# ?o wdt:P31 ?o2 .

# ?o <http://schema.org/name> ?olbl .
# ?o2 <http://schema.org/name> ?o2lbl .

} 
ORDER BY ?olbl
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('o', 'http://www.wikidata.org/entity/Q2455835'), ('olbl', 'Woody Allen filmography'), ('o2', 'http://www.wikidata.org/entity/Q1371849'), ('o2lbl', 'filmography')]
# 1

# %%
# get predicates from "Woody Allen filmography"

queryString = """
SELECT DISTINCT ?p ?plbl
WHERE { 

wd:Q2455835 ?p ?o .

# ?p <http://schema.org/name> ?plbl .

} 
ORDER BY ?plbl
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P646'), ('plbl', 'Freebase ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3417'), ('plbl', 'Quora topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P18'), ('plbl', 'image')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('plbl', 'instance of')]
# [('p', 'http://www.wikidata.org/prop/direct/P360'), ('plbl', 'is a list of')]
# [('p', 'http://www.wikidata.org/prop/direct/P921'), ('plbl', 'main subject')]
# 6

# %%
# get object from "Woody Allen filmography"->"is a list of"

queryString = """
SELECT DISTINCT ?o ?olbl
WHERE { 


wd:Q2455835 wdt:P360 ?o .

# ?o <http://schema.org/name> ?olbl .

} 
ORDER BY ?olbl
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('o', 'http://www.wikidata.org/entity/Q11424'), ('olbl', 'film')]
# 1

# %%
# get predicates from node "film"

queryString = """
SELECT DISTINCT ?p ?plbl
WHERE { 


wd:Q11424 ?p ?o .

# ?p <http://schema.org/name> ?plbl .

} 
ORDER BY ?plbl
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P5198'), ('plbl', 'ASC Leiden Thesaurus ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1014'), ('plbl', 'Art & Architecture Thesaurus ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7033'), ('plbl', 'Australian Educational Vocabulary ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6200'), ('plbl', 'BBC News topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1617'), ('plbl', 'BBC Things ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P508'), ('plbl', 'BNCF Thesaurus ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2581'), ('plbl', 'BabelNet ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P950'), ('plbl', 'Biblioteca Nacional de España ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P268'), ('plbl', 'Bibliothèque nationale de France ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7685'), ('plbl', 'CALS Encyclopedia of Arkansas ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P373'), ('plbl', 'Commons category')]
# [('p', 'http://www.wikidata.org/prop/direct/P1036'), ('plbl', 'Dewey Decimal Classification')]
# [('p', 'http://www.wikidata.org/prop/direct/P9545'), ('plbl', 'Encyclopedia of China Online Database ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1417'), ('plbl', 'Encyclopædia Britannica Online ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3832'), ('plbl', 'Europeana Fashion Vocabulary ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P646'), ('plbl', 'Freebase ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7818'), ('plbl', 'French Vikidia ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P227'), ('plbl', 'GND ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3106'), ('plbl', 'Guardian topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5250'), ('plbl', 'IAB code')]
# [('p', 'http://www.wikidata.org/prop/direct/P1256'), ('plbl', 'Iconclass notation')]
# [('p', 'http://www.wikidata.org/prop/direct/P3827'), ('plbl', 'JSTOR topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8408'), ('plbl', 'KBpedia ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6573'), ('plbl', 'Klexikon article ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1368'), ('plbl', 'LNB ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P244'), ('plbl', 'Library of Congress authority ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P4953'), ('plbl', 'Library of Congress Genre/Form Terms ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7697'), ('plbl', 'Maine: An Encyclopedia ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P486'), ('plbl', 'MeSH descriptor ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7688'), ('plbl', 'Mississippi Encyclopedia ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P349'), ('plbl', 'National Diet Library ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3221'), ('plbl', 'New York Times topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7749'), ('plbl', 'Nomenclature for Museum Cataloging')]
# [('p', 'http://www.wikidata.org/prop/direct/P1245'), ('plbl', 'OmegaWiki Defined Meaning')]
# [('p', 'http://www.wikidata.org/prop/direct/P1051'), ('plbl', 'PSH ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6328'), ('plbl', 'Politika topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3417'), ('plbl', 'Quora topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8519'), ('plbl', 'RKD thesaurus ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3911'), ('plbl', 'STW Thesaurus for Economics ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7827'), ('plbl', 'Spanish Vikidia ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2612'), ('plbl', 'TED topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5357'), ('plbl', 'The Encyclopedia of Science Fiction ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7952'), ('plbl', 'The First Amendment Encyclopedia ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8672'), ('plbl', 'Twitter topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1225'), ('plbl', 'U.S. National Archives Identifier')]
# [('p', 'http://www.wikidata.org/prop/direct/P4527'), ('plbl', 'UK Parliament thesaurus ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3916'), ('plbl', 'UNESCO Thesaurus ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2167'), ('plbl', 'UNSPSC Code')]
# [('p', 'http://www.wikidata.org/prop/direct/P3921'), ('plbl', 'Wikidata SPARQL query equivalent')]
# [('p', 'http://www.wikidata.org/prop/direct/P5125'), ('plbl', 'Wikimedia outline')]
# [('p', 'http://www.wikidata.org/prop/direct/P7497'), ('plbl', 'Wolfram Language entity type')]
# [('p', 'http://www.wikidata.org/prop/direct/P2347'), ('plbl', 'YSO ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8309'), ('plbl', 'Yle topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3553'), ('plbl', 'Zhihu topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6186'), ('plbl', 'category for eponymous categories')]
# [('p', 'http://www.wikidata.org/prop/direct/P1343'), ('plbl', 'described by source')]
# [('p', 'http://www.wikidata.org/prop/direct/P1889'), ('plbl', 'different from')]
# [('p', 'http://www.wikidata.org/prop/direct/P1709'), ('plbl', 'equivalent class')]
# [('p', 'http://www.wikidata.org/prop/direct/P2888'), ('plbl', 'exact match')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('plbl', 'has part')]
# [('p', 'http://www.wikidata.org/prop/direct/P18'), ('plbl', 'image')]
# [('p', 'http://www.wikidata.org/prop/direct/P6104'), ('plbl', 'maintained by WikiProject')]
# [('p', 'http://www.wikidata.org/prop/direct/P5869'), ('plbl', 'model item')]
# [('p', 'http://www.wikidata.org/prop/direct/P5008'), ('plbl', 'on focus list of Wikimedia project')]
# [('p', 'http://www.wikidata.org/prop/direct/P2959'), ('plbl', 'permanent duplicated item')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('plbl', 'properties for this type')]
# [('p', 'http://www.wikidata.org/prop/direct/P460'), ('plbl', 'said to be the same as')]
# [('p', 'http://www.wikidata.org/prop/direct/P8972'), ('plbl', 'small logo or icon')]
# [('p', 'http://www.wikidata.org/prop/direct/P2579'), ('plbl', 'studied by')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('plbl', 'subclass of')]
# [('p', 'http://www.wikidata.org/prop/direct/P3984'), ('plbl', 'subreddit')]
# [('p', 'http://www.wikidata.org/prop/direct/P1151'), ('plbl', "topic's main Wikimedia portal")]
# [('p', 'http://www.wikidata.org/prop/direct/P910'), ('plbl', "topic's main category")]
# [('p', 'http://www.wikidata.org/prop/direct/P1424'), ('plbl', "topic's main template")]
# [('p', 'http://www.wikidata.org/prop/direct/P9318'), ('plbl', 'Ávvir topic ID')]
# 75

# %%
# get class of which "film" is a subclass

queryString = """
SELECT DISTINCT ?o ?olbl
WHERE { 


wd:Q11424 wdt:P279 ?o .

# ?o <http://schema.org/name> ?olbl .

} 
ORDER BY ?olbl
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('o', 'http://www.wikidata.org/entity/Q2431196'), ('olbl', 'audiovisual work')]
# [('o', 'http://www.wikidata.org/entity/Q10301427'), ('olbl', 'moving image')]
# [('o', 'http://www.wikidata.org/entity/Q20937557'), ('olbl', 'series')]
# [('o', 'http://www.wikidata.org/entity/Q4502142'), ('olbl', 'visual artwork')]
# 4

# %%
# get predicates to "film"

queryString = """
SELECT DISTINCT ?p ?plbl
WHERE { 


# ?s ?p wd:Q11424 .

# ?p <http://schema.org/name> ?plbl .

} 
ORDER BY ?plbl
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P1204'), ('plbl', "Wikimedia portal's main topic")]
# [('p', 'http://www.wikidata.org/prop/direct/P971'), ('plbl', 'category combines topics')]
# [('p', 'http://www.wikidata.org/prop/direct/P4224'), ('plbl', 'category contains')]
# [('p', 'http://www.wikidata.org/prop/direct/P301'), ('plbl', "category's main topic")]
# [('p', 'http://www.wikidata.org/prop/direct/P180'), ('plbl', 'depicts')]
# [('p', 'http://www.wikidata.org/prop/direct/P1889'), ('plbl', 'different from')]
# [('p', 'http://www.wikidata.org/prop/direct/P437'), ('plbl', 'distribution format')]
# [('p', 'http://www.wikidata.org/prop/direct/P8115'), ('plbl', 'eligible recipient')]
# [('p', 'http://www.wikidata.org/prop/direct/P1574'), ('plbl', 'exemplar of')]
# [('p', 'http://www.wikidata.org/prop/direct/P2079'), ('plbl', 'fabrication method')]
# [('p', 'http://www.wikidata.org/prop/direct/P1269'), ('plbl', 'facet of')]
# [('p', 'http://www.wikidata.org/prop/direct/P1074'), ('plbl', 'fictional analog of')]
# [('p', 'http://www.wikidata.org/prop/direct/P425'), ('plbl', 'field of this occupation')]
# [('p', 'http://www.wikidata.org/prop/direct/P101'), ('plbl', 'field of work')]
# [('p', 'http://www.wikidata.org/prop/direct/P136'), ('plbl', 'genre')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('plbl', 'has part')]
# [('p', 'http://www.wikidata.org/prop/direct/P2670'), ('plbl', 'has parts of the class')]
# [('p', 'http://www.wikidata.org/prop/direct/P452'), ('plbl', 'industry')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('plbl', 'instance of')]
# [('p', 'http://www.wikidata.org/prop/direct/P2650'), ('plbl', 'interested in')]
# [('p', 'http://www.wikidata.org/prop/direct/P360'), ('plbl', 'is a list of')]
# [('p', 'http://www.wikidata.org/prop/direct/P8225'), ('plbl', 'is metaclass for')]
# [('p', 'http://www.wikidata.org/prop/direct/P276'), ('plbl', 'location')]
# [('p', 'http://www.wikidata.org/prop/direct/P186'), ('plbl', 'made from material')]
# [('p', 'http://www.wikidata.org/prop/direct/P921'), ('plbl', 'main subject')]
# [('p', 'http://www.wikidata.org/prop/direct/P135'), ('plbl', 'movement')]
# [('p', 'http://www.wikidata.org/prop/direct/P106'), ('plbl', 'occupation')]
# [('p', 'http://www.wikidata.org/prop/direct/P364'), ('plbl', 'original language of film or TV show')]
# [('p', 'http://www.wikidata.org/prop/direct/P361'), ('plbl', 'part of')]
# [('p', 'http://www.wikidata.org/prop/direct/P2959'), ('plbl', 'permanent duplicated item')]
# [('p', 'http://www.wikidata.org/prop/direct/P1056'), ('plbl', 'product or material produced')]
# [('p', 'http://www.wikidata.org/prop/direct/P460'), ('plbl', 'said to be the same as')]
# [('p', 'http://www.wikidata.org/prop/direct/P2578'), ('plbl', 'studies')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('plbl', 'subclass of')]
# [('p', 'http://www.wikidata.org/prop/direct/P1423'), ('plbl', 'template has topic')]
# [('p', 'http://www.wikidata.org/prop/direct/P366'), ('plbl', 'use')]
# [('p', 'http://www.wikidata.org/prop/direct/P2283'), ('plbl', 'uses')]
# 37

# %%
# GOAL (1)
# get films

queryString = """
SELECT DISTINCT ?film ?flbl
WHERE { 


# ?film wdt:P31 wd:Q11424 .

# ?film <http://schema.org/name> ?flbl .

} 
ORDER BY ?flbl
LIMIT 10
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('film', 'http://www.wikidata.org/entity/Q4540204'), ('flbl', '!Women Art Revolution')]
# [('film', 'http://www.wikidata.org/entity/Q4032288'), ('flbl', '"713" Requests Permission to Land')]
# [('film', 'http://www.wikidata.org/entity/Q93765322'), ('flbl', '"By the railroad" film')]
# [('film', 'http://www.wikidata.org/entity/Q615254'), ('flbl', '"Crocodile" Dundee')]
# [('film', 'http://www.wikidata.org/entity/Q1140745'), ('flbl', '"Crocodile" Dundee II')]
# [('film', 'http://www.wikidata.org/entity/Q16691116'), ('flbl', '"Dream" Agency')]
# [('film', 'http://www.wikidata.org/entity/Q3596104'), ('flbl', '"FF.SS." – Cioè: "...che mi hai portato a fare sopra a Posillipo se non mi vuoi più bene?"')]
# [('film', 'http://www.wikidata.org/entity/Q4540285'), ('flbl', '"Good Hair" and Other Dubious Distinctions')]
# [('film', 'http://www.wikidata.org/entity/Q93764465'), ('flbl', '"Interrogation", film, 1982')]
# [('film', 'http://www.wikidata.org/entity/Q821560'), ('flbl', '"Pimpernel" Smith')]
# 10

# %% [markdown]
# ## Task 2

# %%
# get predicate between "Quentin Tarantino" and "Director"

queryString = """
SELECT DISTINCT ?p ?plbl
WHERE { 


wd:Q3772 ?p wd:Q2526255 .

# ?p <http://schema.org/name> ?plbl .

} 
ORDER BY ?plbl
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P106'), ('plbl', 'occupation')]
# 1

# %%
# GOAL (2)
# get all directors

queryString = """
SELECT DISTINCT ?s ?slbl
WHERE { 


# ?s wdt:P106 wd:Q2526255 .

# ?s <http://schema.org/name> ?slbl .

} 
ORDER BY ?slbl
LIMIT 20
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('s', 'http://www.wikidata.org/entity/Q4544812'), ('slbl', '(Jo)Style')]
# [('s', 'http://www.wikidata.org/entity/Q106992033'), ('slbl', '44aen')]
# [('s', 'http://www.wikidata.org/entity/Q30923004'), ('slbl', '@MARU_movie')]
# [('s', 'http://www.wikidata.org/entity/Q5673777'), ('slbl', 'A Harsha')]
# [('s', 'http://www.wikidata.org/entity/Q22276674'), ('slbl', 'A J Mintu')]
# [('s', 'http://www.wikidata.org/entity/Q93443565'), ('slbl', 'A. B. Comathiere')]
# [('s', 'http://www.wikidata.org/entity/Q4647568'), ('slbl', 'A. B. Raj')]
# [('s', 'http://www.wikidata.org/entity/Q4647596'), ('slbl', 'A. Bhimsingh')]
# [('s', 'http://www.wikidata.org/entity/Q2818908'), ('slbl', 'A. Blaine Miller')]
# [('s', 'http://www.wikidata.org/entity/Q4647628'), ('slbl', 'A. C. Tirulokchandar')]
# [('s', 'http://www.wikidata.org/entity/Q278612'), ('slbl', 'A. D. Flowers')]
# [('s', 'http://www.wikidata.org/entity/Q4647692'), ('slbl', 'A. Dean Bell')]
# [('s', 'http://www.wikidata.org/entity/Q278657'), ('slbl', 'A. Edward Sutherland')]
# [('s', 'http://www.wikidata.org/entity/Q21934080'), ('slbl', 'A. Govindamoorthy')]
# [('s', 'http://www.wikidata.org/entity/Q4647933'), ('slbl', 'A. J. Kardar')]
# [('s', 'http://www.wikidata.org/entity/Q4647972'), ('slbl', 'A. J. Schnack')]
# [('s', 'http://www.wikidata.org/entity/Q17579848'), ('slbl', 'A. Jagannathan')]
# [('s', 'http://www.wikidata.org/entity/Q4648022'), ('slbl', 'A. K. Chettiar')]
# [('s', 'http://www.wikidata.org/entity/Q2582445'), ('slbl', 'A. K. Lohithadas')]
# [('s', 'http://www.wikidata.org/entity/Q4648040'), ('slbl', 'A. K. Sajan')]
# 20

# %% [markdown]
# ## Task 3

# %%
# get predicates to a film

queryString = """
SELECT DISTINCT ?p 
WHERE { 

# ?s ?p wd:Q3596104 .

# ?p <http://schema.org/name> ?plbl .

} 
ORDER BY ?plbl
"""

print("Results")
run_query(queryString)
# Out:
# Results
# Empty
# 0

# %%
# get predicates from a film

queryString = """
SELECT DISTINCT ?p ?plbl
WHERE { 

wd:Q3596104 ?p ?o .

# ?p <http://schema.org/name> ?plbl .

} 
ORDER BY ?plbl
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P4529'), ('plbl', 'Douban film ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2704'), ('plbl', 'EIDR content ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P646'), ('plbl', 'Freebase ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P345'), ('plbl', 'IMDb ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2603'), ('plbl', 'Kinopoisk film ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6127'), ('plbl', 'Letterboxd film ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P4947'), ('plbl', 'TMDb movie ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P161'), ('plbl', 'cast member')]
# [('p', 'http://www.wikidata.org/prop/direct/P462'), ('plbl', 'color')]
# [('p', 'http://www.wikidata.org/prop/direct/P86'), ('plbl', 'composer')]
# [('p', 'http://www.wikidata.org/prop/direct/P495'), ('plbl', 'country of origin')]
# [('p', 'http://www.wikidata.org/prop/direct/P57'), ('plbl', 'director')]
# [('p', 'http://www.wikidata.org/prop/direct/P2047'), ('plbl', 'duration')]
# [('p', 'http://www.wikidata.org/prop/direct/P136'), ('plbl', 'genre')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('plbl', 'instance of')]
# [('p', 'http://www.wikidata.org/prop/direct/P840'), ('plbl', 'narrative location')]
# [('p', 'http://www.wikidata.org/prop/direct/P364'), ('plbl', 'original language of film or TV show')]
# [('p', 'http://www.wikidata.org/prop/direct/P162'), ('plbl', 'producer')]
# [('p', 'http://www.wikidata.org/prop/direct/P577'), ('plbl', 'publication date')]
# [('p', 'http://www.wikidata.org/prop/direct/P58'), ('plbl', 'screenwriter')]
# 20

# %%
# GOAL (3)
# get all workers and their roles for each film

queryString = """
SELECT DISTINCT ?film ?flbl ?role ?rlbl ?worker ?wlbl
WHERE { 

# ?film wdt:P31 wd:Q11424 ;
    # ?role ?worker .
    
# ?worker wdt:P31 wd:Q5 .

# ?film <http://schema.org/name> ?flbl .
# ?worker <http://schema.org/name> ?wlbl .
# ?role <http://schema.org/name> ?rlbl .

} 
ORDER BY ?flbl ?wlbl
LIMIT 40
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('film', 'http://www.wikidata.org/entity/Q4540204'), ('flbl', '!Women Art Revolution'), ('role', 'http://www.wikidata.org/prop/direct/P86'), ('rlbl', 'composer'), ('worker', 'http://www.wikidata.org/entity/Q2940239'), ('wlbl', 'Carrie Brownstein')]
# [('film', 'http://www.wikidata.org/entity/Q4540204'), ('flbl', '!Women Art Revolution'), ('role', 'http://www.wikidata.org/prop/direct/P57'), ('rlbl', 'director'), ('worker', 'http://www.wikidata.org/entity/Q6709060'), ('wlbl', 'Lynn Hershman Leeson')]
# [('film', 'http://www.wikidata.org/entity/Q4540204'), ('flbl', '!Women Art Revolution'), ('role', 'http://www.wikidata.org/prop/direct/P58'), ('rlbl', 'screenwriter'), ('worker', 'http://www.wikidata.org/entity/Q6709060'), ('wlbl', 'Lynn Hershman Leeson')]
# [('film', 'http://www.wikidata.org/entity/Q4032288'), ('flbl', '"713" Requests Permission to Land'), ('role', 'http://www.wikidata.org/prop/direct/P86'), ('rlbl', 'composer'), ('worker', 'http://www.wikidata.org/entity/Q4373271'), ('wlbl', 'Georgy Portnov')]
# [('film', 'http://www.wikidata.org/entity/Q4032288'), ('flbl', '"713" Requests Permission to Land'), ('role', 'http://www.wikidata.org/prop/direct/P57'), ('rlbl', 'director'), ('worker', 'http://www.wikidata.org/entity/Q4321210'), ('wlbl', 'Grigori Nikulin')]
# [('film', 'http://www.wikidata.org/entity/Q4032288'), ('flbl', '"713" Requests Permission to Land'), ('role', 'http://www.wikidata.org/prop/direct/P161'), ('rlbl', 'cast member'), ('worker', 'http://www.wikidata.org/entity/Q4242001'), ('wlbl', 'Lev Krugly')]
# [('film', 'http://www.wikidata.org/entity/Q4032288'), ('flbl', '"713" Requests Permission to Land'), ('role', 'http://www.wikidata.org/prop/direct/P161'), ('rlbl', 'cast member'), ('worker', 'http://www.wikidata.org/entity/Q4054963'), ('wlbl', 'Lyudmila Abramova')]
# [('film', 'http://www.wikidata.org/entity/Q4032288'), ('flbl', '"713" Requests Permission to Land'), ('role', 'http://www.wikidata.org/prop/direct/P161'), ('rlbl', 'cast member'), ('worker', 'http://www.wikidata.org/entity/Q1967346'), ('wlbl', 'Otar Koberidze')]
# [('film', 'http://www.wikidata.org/entity/Q4032288'), ('flbl', '"713" Requests Permission to Land'), ('role', 'http://www.wikidata.org/prop/direct/P344'), ('rlbl', 'director of photography'), ('worker', 'http://www.wikidata.org/entity/Q4256571'), ('wlbl', 'Veniamin Levitin')]
# [('film', 'http://www.wikidata.org/entity/Q4032288'), ('flbl', '"713" Requests Permission to Land'), ('role', 'http://www.wikidata.org/prop/direct/P161'), ('rlbl', 'cast member'), ('worker', 'http://www.wikidata.org/entity/Q4514928'), ('wlbl', 'Vladimir Chestnokov')]
# [('film', 'http://www.wikidata.org/entity/Q4032288'), ('flbl', '"713" Requests Permission to Land'), ('role', 'http://www.wikidata.org/prop/direct/P161'), ('rlbl', 'cast member'), ('worker', 'http://www.wikidata.org/entity/Q512'), ('wlbl', 'Vladimir Vysotsky')]
# [('film', 'http://www.wikidata.org/entity/Q93765322'), ('flbl', '"By the railroad" film'), ('role', 'http://www.wikidata.org/prop/direct/P170'), ('rlbl', 'creator'), ('worker', 'http://www.wikidata.org/entity/Q92095342'), ('wlbl', 'Andrzej Brzozowski')]
# [('film', 'http://www.wikidata.org/entity/Q615254'), ('flbl', '"Crocodile" Dundee'), ('role', 'http://www.wikidata.org/prop/direct/P161'), ('rlbl', 'cast member'), ('worker', 'http://www.wikidata.org/entity/Q731111'), ('wlbl', 'David Gulpilil')]
# [('film', 'http://www.wikidata.org/entity/Q615254'), ('flbl', '"Crocodile" Dundee'), ('role', 'http://www.wikidata.org/prop/direct/P1040'), ('rlbl', 'film editor'), ('worker', 'http://www.wikidata.org/entity/Q19502152'), ('wlbl', 'David Stiven')]
# [('film', 'http://www.wikidata.org/entity/Q615254'), ('flbl', '"Crocodile" Dundee'), ('role', 'http://www.wikidata.org/prop/direct/P162'), ('rlbl', 'producer'), ('worker', 'http://www.wikidata.org/entity/Q153379'), ('wlbl', 'John Cornell')]
# [('film', 'http://www.wikidata.org/entity/Q615254'), ('flbl', '"Crocodile" Dundee'), ('role', 'http://www.wikidata.org/prop/direct/P58'), ('rlbl', 'screenwriter'), ('worker', 'http://www.wikidata.org/entity/Q153379'), ('wlbl', 'John Cornell')]
# [('film', 'http://www.wikidata.org/entity/Q615254'), ('flbl', '"Crocodile" Dundee'), ('role', 'http://www.wikidata.org/prop/direct/P161'), ('rlbl', 'cast member'), ('worker', 'http://www.wikidata.org/entity/Q441661'), ('wlbl', 'John Meillon')]
# [('film', 'http://www.wikidata.org/entity/Q615254'), ('flbl', '"Crocodile" Dundee'), ('role', 'http://www.wikidata.org/prop/direct/P58'), ('rlbl', 'screenwriter'), ('worker', 'http://www.wikidata.org/entity/Q3195086'), ('wlbl', 'Ken Shadie')]
# [('film', 'http://www.wikidata.org/entity/Q615254'), ('flbl', '"Crocodile" Dundee'), ('role', 'http://www.wikidata.org/prop/direct/P161'), ('rlbl', 'cast member'), ('worker', 'http://www.wikidata.org/entity/Q235100'), ('wlbl', 'Linda Kozlowski')]
# [('film', 'http://www.wikidata.org/entity/Q615254'), ('flbl', '"Crocodile" Dundee'), ('role', 'http://www.wikidata.org/prop/direct/P161'), ('rlbl', 'cast member'), ('worker', 'http://www.wikidata.org/entity/Q1868688'), ('wlbl', 'Mark Blum')]
# [('film', 'http://www.wikidata.org/entity/Q615254'), ('flbl', '"Crocodile" Dundee'), ('role', 'http://www.wikidata.org/prop/direct/P161'), ('rlbl', 'cast member'), ('worker', 'http://www.wikidata.org/entity/Q296641'), ('wlbl', 'Paul Hogan')]
# [('film', 'http://www.wikidata.org/entity/Q615254'), ('flbl', '"Crocodile" Dundee'), ('role', 'http://www.wikidata.org/prop/direct/P58'), ('rlbl', 'screenwriter'), ('worker', 'http://www.wikidata.org/entity/Q296641'), ('wlbl', 'Paul Hogan')]
# [('film', 'http://www.wikidata.org/entity/Q615254'), ('flbl', '"Crocodile" Dundee'), ('role', 'http://www.wikidata.org/prop/direct/P86'), ('rlbl', 'composer'), ('worker', 'http://www.wikidata.org/entity/Q7172812'), ('wlbl', 'Peter Best')]
# [('film', 'http://www.wikidata.org/entity/Q615254'), ('flbl', '"Crocodile" Dundee'), ('role', 'http://www.wikidata.org/prop/direct/P57'), ('rlbl', 'director'), ('worker', 'http://www.wikidata.org/entity/Q7173921'), ('wlbl', 'Peter Faiman')]
# [('film', 'http://www.wikidata.org/entity/Q615254'), ('flbl', '"Crocodile" Dundee'), ('role', 'http://www.wikidata.org/prop/direct/P161'), ('rlbl', 'cast member'), ('worker', 'http://www.wikidata.org/entity/Q470153'), ('wlbl', 'Reginald VelJohnson')]
# [('film', 'http://www.wikidata.org/entity/Q615254'), ('flbl', '"Crocodile" Dundee'), ('role', 'http://www.wikidata.org/prop/direct/P344'), ('rlbl', 'director of photography'), ('worker', 'http://www.wikidata.org/entity/Q260963'), ('wlbl', 'Russell Boyd')]
# [('film', 'http://www.wikidata.org/entity/Q1140745'), ('flbl', '"Crocodile" Dundee II'), ('role', 'http://www.wikidata.org/prop/direct/P161'), ('rlbl', 'cast member'), ('worker', 'http://www.wikidata.org/entity/Q16202313'), ('wlbl', 'Carlos Carrasco')]
# [('film', 'http://www.wikidata.org/entity/Q1140745'), ('flbl', '"Crocodile" Dundee II'), ('role', 'http://www.wikidata.org/prop/direct/P161'), ('rlbl', 'cast member'), ('worker', 'http://www.wikidata.org/entity/Q706513'), ('wlbl', 'Charles S. Dutton')]
# [('film', 'http://www.wikidata.org/entity/Q1140745'), ('flbl', '"Crocodile" Dundee II'), ('role', 'http://www.wikidata.org/prop/direct/P161'), ('rlbl', 'cast member'), ('worker', 'http://www.wikidata.org/entity/Q2982646'), ('wlbl', 'Colin Quinn')]
# [('film', 'http://www.wikidata.org/entity/Q1140745'), ('flbl', '"Crocodile" Dundee II'), ('role', 'http://www.wikidata.org/prop/direct/P1040'), ('rlbl', 'film editor'), ('worker', 'http://www.wikidata.org/entity/Q19502152'), ('wlbl', 'David Stiven')]
# [('film', 'http://www.wikidata.org/entity/Q1140745'), ('flbl', '"Crocodile" Dundee II'), ('role', 'http://www.wikidata.org/prop/direct/P161'), ('rlbl', 'cast member'), ('worker', 'http://www.wikidata.org/entity/Q1188980'), ('wlbl', 'Dennis Boutsikaris')]
# [('film', 'http://www.wikidata.org/entity/Q1140745'), ('flbl', '"Crocodile" Dundee II'), ('role', 'http://www.wikidata.org/prop/direct/P161'), ('rlbl', 'cast member'), ('worker', 'http://www.wikidata.org/entity/Q3057304'), ('wlbl', 'Ernie Dingo')]
# [('film', 'http://www.wikidata.org/entity/Q1140745'), ('flbl', '"Crocodile" Dundee II'), ('role', 'http://www.wikidata.org/prop/direct/P161'), ('rlbl', 'cast member'), ('worker', 'http://www.wikidata.org/entity/Q2646713'), ('wlbl', 'Gregory Jbara')]
# [('film', 'http://www.wikidata.org/entity/Q1140745'), ('flbl', '"Crocodile" Dundee II'), ('role', 'http://www.wikidata.org/prop/direct/P161'), ('rlbl', 'cast member'), ('worker', 'http://www.wikidata.org/entity/Q1555323'), ('wlbl', 'Gus Mercurio')]
# [('film', 'http://www.wikidata.org/entity/Q1140745'), ('flbl', '"Crocodile" Dundee II'), ('role', 'http://www.wikidata.org/prop/direct/P161'), ('rlbl', 'cast member'), ('worker', 'http://www.wikidata.org/entity/Q1676908'), ('wlbl', 'Jace Alexander')]
# [('film', 'http://www.wikidata.org/entity/Q1140745'), ('flbl', '"Crocodile" Dundee II'), ('role', 'http://www.wikidata.org/prop/direct/P162'), ('rlbl', 'producer'), ('worker', 'http://www.wikidata.org/entity/Q153379'), ('wlbl', 'John Cornell')]
# [('film', 'http://www.wikidata.org/entity/Q1140745'), ('flbl', '"Crocodile" Dundee II'), ('role', 'http://www.wikidata.org/prop/direct/P57'), ('rlbl', 'director'), ('worker', 'http://www.wikidata.org/entity/Q153379'), ('wlbl', 'John Cornell')]
# [('film', 'http://www.wikidata.org/entity/Q1140745'), ('flbl', '"Crocodile" Dundee II'), ('role', 'http://www.wikidata.org/prop/direct/P161'), ('rlbl', 'cast member'), ('worker', 'http://www.wikidata.org/entity/Q441661'), ('wlbl', 'John Meillon')]
# [('film', 'http://www.wikidata.org/entity/Q1140745'), ('flbl', '"Crocodile" Dundee II'), ('role', 'http://www.wikidata.org/prop/direct/P161'), ('rlbl', 'cast member'), ('worker', 'http://www.wikidata.org/entity/Q1710454'), ('wlbl', 'Juan Fernández de Alarcón')]
# [('film', 'http://www.wikidata.org/entity/Q1140745'), ('flbl', '"Crocodile" Dundee II'), ('role', 'http://www.wikidata.org/prop/direct/P161'), ('rlbl', 'cast member'), ('worker', 'http://www.wikidata.org/entity/Q918404'), ('wlbl', 'Kenneth Welsh')]
# 40

# %% [markdown]
# ## Task 4

# %%
# get all films directed by Quentin Tarantino or Woody Allen

queryString = """
SELECT DISTINCT ?film ?flbl ?dir
WHERE { 

{
    # ?film wdt:P31 wd:Q11424 ;
        # ?role ?worker .

    # ?film wdt:P57 wd:Q3772 .

    # ?film <http://schema.org/name> ?flbl .
    wd:Q3772 <http://schema.org/name> ?dir .
}
UNION
{
    # ?film wdt:P31 wd:Q11424 ;
        # ?role ?worker .

    # ?film wdt:P57 wd:Q25089 .

    # ?film <http://schema.org/name> ?flbl .
    wd:Q25089 <http://schema.org/name> ?dir .
}

FILTER (?role != wdt:P57)

} 
ORDER BY ?flbl
LIMIT 40
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('film', 'http://www.wikidata.org/entity/Q1306629'), ('flbl', "A Midsummer Night's Sex Comedy"), ('dir', 'Woody Allen')]
# [('film', 'http://www.wikidata.org/entity/Q42307699'), ('flbl', 'A Rainy Day in New York'), ('dir', 'Woody Allen')]
# [('film', 'http://www.wikidata.org/entity/Q682262'), ('flbl', 'Alice'), ('dir', 'Woody Allen')]
# [('film', 'http://www.wikidata.org/entity/Q233464'), ('flbl', 'Annie Hall'), ('dir', 'Woody Allen')]
# [('film', 'http://www.wikidata.org/entity/Q541185'), ('flbl', 'Another Woman'), ('dir', 'Woody Allen')]
# [('film', 'http://www.wikidata.org/entity/Q614009'), ('flbl', 'Anything Else'), ('dir', 'Woody Allen')]
# [('film', 'http://www.wikidata.org/entity/Q806092'), ('flbl', 'Bananas'), ('dir', 'Woody Allen')]
# [('film', 'http://www.wikidata.org/entity/Q2907178'), ('flbl', 'Blue Jasmine'), ('dir', 'Woody Allen')]
# [('film', 'http://www.wikidata.org/entity/Q729026'), ('flbl', 'Broadway Danny Rose'), ('dir', 'Woody Allen')]
# [('film', 'http://www.wikidata.org/entity/Q1004531'), ('flbl', 'Bullets Over Broadway'), ('dir', 'Woody Allen')]
# [('film', 'http://www.wikidata.org/entity/Q20950014'), ('flbl', 'Café Society'), ('dir', 'Woody Allen')]
# [('film', 'http://www.wikidata.org/entity/Q833530'), ('flbl', "Cassandra's Dream"), ('dir', 'Woody Allen')]
# [('film', 'http://www.wikidata.org/entity/Q1052826'), ('flbl', 'Celebrity'), ('dir', 'Woody Allen')]
# [('film', 'http://www.wikidata.org/entity/Q181555'), ('flbl', 'Crimes and Misdemeanors'), ('dir', 'Woody Allen')]
# [('film', 'http://www.wikidata.org/entity/Q1137310'), ('flbl', 'Death Proof'), ('dir', 'Quentin Tarantino')]
# [('film', 'http://www.wikidata.org/entity/Q551762'), ('flbl', 'Deconstructing Harry'), ('dir', 'Woody Allen')]
# [('film', 'http://www.wikidata.org/entity/Q571032'), ('flbl', 'Django Unchained'), ('dir', 'Quentin Tarantino')]
# [('film', 'http://www.wikidata.org/entity/Q1334572'), ('flbl', 'Everyone Says I Love You'), ('dir', 'Woody Allen')]
# [('film', 'http://www.wikidata.org/entity/Q499697'), ('flbl', 'Everything You Always Wanted to Know About Sex*'), ('dir', 'Woody Allen')]
# [('film', 'http://www.wikidata.org/entity/Q845057'), ('flbl', 'Hannah and Her Sisters'), ('dir', 'Woody Allen')]
# [('film', 'http://www.wikidata.org/entity/Q582021'), ('flbl', 'Hollywood Ending'), ('dir', 'Woody Allen')]
# [('film', 'http://www.wikidata.org/entity/Q740143'), ('flbl', 'Husbands and Wives'), ('dir', 'Woody Allen')]
# [('film', 'http://www.wikidata.org/entity/Q153723'), ('flbl', 'Inglourious Basterds'), ('dir', 'Quentin Tarantino')]
# [('film', 'http://www.wikidata.org/entity/Q961403'), ('flbl', 'Interiors'), ('dir', 'Woody Allen')]
# [('film', 'http://www.wikidata.org/entity/Q17417520'), ('flbl', 'Irrational Man'), ('dir', 'Woody Allen')]
# [('film', 'http://www.wikidata.org/entity/Q431252'), ('flbl', 'Jackie Brown'), ('dir', 'Quentin Tarantino')]
# [('film', 'http://www.wikidata.org/entity/Q165325'), ('flbl', 'Kill Bill Volume 1'), ('dir', 'Quentin Tarantino')]
# [('film', 'http://www.wikidata.org/entity/Q928019'), ('flbl', 'Kill Bill Volume 2'), ('dir', 'Quentin Tarantino')]
# [('film', 'http://www.wikidata.org/entity/Q18126825'), ('flbl', 'Kill Bill: The Whole Bloody Affair'), ('dir', 'Quentin Tarantino')]
# [('film', 'http://www.wikidata.org/entity/Q1218888'), ('flbl', 'Love and Death'), ('dir', 'Woody Allen')]
# [('film', 'http://www.wikidata.org/entity/Q14511869'), ('flbl', 'Magic in the Moonlight'), ('dir', 'Woody Allen')]
# [('film', 'http://www.wikidata.org/entity/Q731310'), ('flbl', 'Manhattan'), ('dir', 'Woody Allen')]
# [('film', 'http://www.wikidata.org/entity/Q1133277'), ('flbl', 'Manhattan Murder Mystery'), ('dir', 'Woody Allen')]
# [('film', 'http://www.wikidata.org/entity/Q733677'), ('flbl', 'Match Point'), ('dir', 'Woody Allen')]
# [('film', 'http://www.wikidata.org/entity/Q1354121'), ('flbl', 'Melinda and Melinda'), ('dir', 'Woody Allen')]
# [('film', 'http://www.wikidata.org/entity/Q206124'), ('flbl', 'Midnight in Paris'), ('dir', 'Woody Allen')]
# [('film', 'http://www.wikidata.org/entity/Q1354109'), ('flbl', 'Mighty Aphrodite'), ('dir', 'Woody Allen')]
# [('film', 'http://www.wikidata.org/entity/Q977372'), ('flbl', 'New York Stories'), ('dir', 'Woody Allen')]
# [('film', 'http://www.wikidata.org/entity/Q47300912'), ('flbl', 'Once Upon a Time in Hollywood'), ('dir', 'Quentin Tarantino')]
# [('film', 'http://www.wikidata.org/entity/Q104123'), ('flbl', 'Pulp Fiction'), ('dir', 'Quentin Tarantino')]
# 40

# %%
# get objects of Woody Allen for "award received", "list of work" and "work period (start)"

queryString = """
SELECT DISTINCT ?aw ?awlbl ?low ?lowlbl ?wp
WHERE { 

wd:Q25089 wdt:P166 ?aw ;
    wdt:P1455 ?low ;
    wdt:P2031 ?wp .

# ?aw <http://schema.org/name> ?awlbl .
# ?low <http://schema.org/name> ?lowlbl .

} 
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('aw', 'http://www.wikidata.org/entity/Q1415017'), ('awlbl', 'Writers Guild of America Award'), ('low', 'http://www.wikidata.org/entity/Q16971520'), ('lowlbl', 'Woody Allen bibliography'), ('wp', '1950-01-01T00:00:00Z')]
# [('aw', 'http://www.wikidata.org/entity/Q13452531'), ('awlbl', 'Commandeur des Arts et des Lettres\u200e'), ('low', 'http://www.wikidata.org/entity/Q16971520'), ('lowlbl', 'Woody Allen bibliography'), ('wp', '1950-01-01T00:00:00Z')]
# [('aw', 'http://www.wikidata.org/entity/Q41375'), ('awlbl', 'BAFTA Award for Best Original Screenplay'), ('low', 'http://www.wikidata.org/entity/Q16971520'), ('lowlbl', 'Woody Allen bibliography'), ('wp', '1950-01-01T00:00:00Z')]
# [('aw', 'http://www.wikidata.org/entity/Q50616934'), ('awlbl', 'honorary doctorate of Pompeu Fabra University'), ('low', 'http://www.wikidata.org/entity/Q16971520'), ('lowlbl', 'Woody Allen bibliography'), ('wp', '1950-01-01T00:00:00Z')]
# [('aw', 'http://www.wikidata.org/entity/Q1111310'), ('awlbl', 'Directors Guild of America Award'), ('low', 'http://www.wikidata.org/entity/Q16971520'), ('lowlbl', 'Woody Allen bibliography'), ('wp', '1950-01-01T00:00:00Z')]
# [('aw', 'http://www.wikidata.org/entity/Q889842'), ('awlbl', 'Bodil Awards'), ('low', 'http://www.wikidata.org/entity/Q16971520'), ('lowlbl', 'Woody Allen bibliography'), ('wp', '1950-01-01T00:00:00Z')]
# [('aw', 'http://www.wikidata.org/entity/Q52382875'), ('awlbl', 'AAAS Fellow'), ('low', 'http://www.wikidata.org/entity/Q16971520'), ('lowlbl', 'Woody Allen bibliography'), ('wp', '1950-01-01T00:00:00Z')]
# [('aw', 'http://www.wikidata.org/entity/Q31579'), ('awlbl', 'David di Donatello'), ('low', 'http://www.wikidata.org/entity/Q16971520'), ('lowlbl', 'Woody Allen bibliography'), ('wp', '1950-01-01T00:00:00Z')]
# [('aw', 'http://www.wikidata.org/entity/Q787148'), ('awlbl', 'Academy Fellowship Award'), ('low', 'http://www.wikidata.org/entity/Q16971520'), ('lowlbl', 'Woody Allen bibliography'), ('wp', '1950-01-01T00:00:00Z')]
# [('aw', 'http://www.wikidata.org/entity/Q3319305'), ('awlbl', 'Princess of Asturias Award for the Arts'), ('low', 'http://www.wikidata.org/entity/Q16971520'), ('lowlbl', 'Woody Allen bibliography'), ('wp', '1950-01-01T00:00:00Z')]
# [('aw', 'http://www.wikidata.org/entity/Q3822438'), ('awlbl', 'Butaca Awards'), ('low', 'http://www.wikidata.org/entity/Q16971520'), ('lowlbl', 'Woody Allen bibliography'), ('wp', '1950-01-01T00:00:00Z')]
# [('aw', 'http://www.wikidata.org/entity/Q19339'), ('awlbl', 'O. Henry Award'), ('low', 'http://www.wikidata.org/entity/Q16971520'), ('lowlbl', 'Woody Allen bibliography'), ('wp', '1950-01-01T00:00:00Z')]
# [('aw', 'http://www.wikidata.org/entity/Q174389'), ('awlbl', 'César Award'), ('low', 'http://www.wikidata.org/entity/Q16971520'), ('lowlbl', 'Woody Allen bibliography'), ('wp', '1950-01-01T00:00:00Z')]
# [('aw', 'http://www.wikidata.org/entity/Q768476'), ('awlbl', 'David di Donatello for Best Film'), ('low', 'http://www.wikidata.org/entity/Q16971520'), ('lowlbl', 'Woody Allen bibliography'), ('wp', '1950-01-01T00:00:00Z')]
# [('aw', 'http://www.wikidata.org/entity/Q3404523'), ('awlbl', 'David di Donatello for Best Foreign Actor'), ('low', 'http://www.wikidata.org/entity/Q16971520'), ('lowlbl', 'Woody Allen bibliography'), ('wp', '1950-01-01T00:00:00Z')]
# [('aw', 'http://www.wikidata.org/entity/Q908858'), ('awlbl', 'Donostia Award'), ('low', 'http://www.wikidata.org/entity/Q16971520'), ('lowlbl', 'Woody Allen bibliography'), ('wp', '1950-01-01T00:00:00Z')]
# [('aw', 'http://www.wikidata.org/entity/Q787131'), ('awlbl', 'BAFTA Award for Best Direction'), ('low', 'http://www.wikidata.org/entity/Q16971520'), ('lowlbl', 'Woody Allen bibliography'), ('wp', '1950-01-01T00:00:00Z')]
# [('aw', 'http://www.wikidata.org/entity/Q103360'), ('awlbl', 'Academy Award for Best Director'), ('low', 'http://www.wikidata.org/entity/Q16971520'), ('lowlbl', 'Woody Allen bibliography'), ('wp', '1950-01-01T00:00:00Z')]
# [('aw', 'http://www.wikidata.org/entity/Q670282'), ('awlbl', 'Golden Globe Award for Best Motion Picture – Musical or Comedy'), ('low', 'http://www.wikidata.org/entity/Q16971520'), ('lowlbl', 'Woody Allen bibliography'), ('wp', '1950-01-01T00:00:00Z')]
# [('aw', 'http://www.wikidata.org/entity/Q41417'), ('awlbl', 'Academy Award for Best Writing, Original Screenplay'), ('low', 'http://www.wikidata.org/entity/Q16971520'), ('lowlbl', 'Woody Allen bibliography'), ('wp', '1950-01-01T00:00:00Z')]
# [('aw', 'http://www.wikidata.org/entity/Q3241784'), ('awlbl', 'Golden Lion for Lifetime Achievements'), ('low', 'http://www.wikidata.org/entity/Q16971520'), ('lowlbl', 'Woody Allen bibliography'), ('wp', '1950-01-01T00:00:00Z')]
# [('aw', 'http://www.wikidata.org/entity/Q2372386'), ('awlbl', 'Sant Jordi Prize'), ('low', 'http://www.wikidata.org/entity/Q16971520'), ('lowlbl', 'Woody Allen bibliography'), ('wp', '1950-01-01T00:00:00Z')]
# [('aw', 'http://www.wikidata.org/entity/Q2418096'), ('awlbl', 'Goya Award for Best European Film'), ('low', 'http://www.wikidata.org/entity/Q16971520'), ('lowlbl', 'Woody Allen bibliography'), ('wp', '1950-01-01T00:00:00Z')]
# [('aw', 'http://www.wikidata.org/entity/Q1789102'), ('awlbl', 'National Board of Review Award for Best Film'), ('low', 'http://www.wikidata.org/entity/Q16971520'), ('lowlbl', 'Woody Allen bibliography'), ('wp', '1950-01-01T00:00:00Z')]
# [('aw', 'http://www.wikidata.org/entity/Q139184'), ('awlbl', 'BAFTA Award for Best Film'), ('low', 'http://www.wikidata.org/entity/Q16971520'), ('lowlbl', 'Woody Allen bibliography'), ('wp', '1950-01-01T00:00:00Z')]
# [('aw', 'http://www.wikidata.org/entity/Q849124'), ('awlbl', 'Golden Globe Award for Best Screenplay'), ('low', 'http://www.wikidata.org/entity/Q16971520'), ('lowlbl', 'Woody Allen bibliography'), ('wp', '1950-01-01T00:00:00Z')]
# [('aw', 'http://www.wikidata.org/entity/Q3404587'), ('awlbl', 'FIPRESCI Prize of the Festival de Cannes'), ('low', 'http://www.wikidata.org/entity/Q16971520'), ('lowlbl', 'Woody Allen bibliography'), ('wp', '1950-01-01T00:00:00Z')]
# [('aw', 'http://www.wikidata.org/entity/Q1170507'), ('awlbl', 'Independent Spirit Award for Best Screenplay'), ('low', 'http://www.wikidata.org/entity/Q16971520'), ('lowlbl', 'Woody Allen bibliography'), ('wp', '1950-01-01T00:00:00Z')]
# [('aw', 'http://www.wikidata.org/entity/Q708135'), ('awlbl', 'Silver Bear'), ('low', 'http://www.wikidata.org/entity/Q16971520'), ('lowlbl', 'Woody Allen bibliography'), ('wp', '1950-01-01T00:00:00Z')]
# 29

# %%
# get node of genders

queryString = """
SELECT DISTINCT ?gender ?glbl
WHERE { 

# ?film wdt:P31 wd:Q11424 ;
    # ?role ?worker .

# ?film wdt:P57 wd:Q3772 .

# ?worker wdt:P31 wd:Q5 ;
        wdt:P21 ?gender .
        
# ?gender <http://schema.org/name> ?glbl .

} 
LIMIT 40
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('gender', 'http://www.wikidata.org/entity/Q6581072'), ('glbl', 'female')]
# [('gender', 'http://www.wikidata.org/entity/Q6581097'), ('glbl', 'male')]
# [('gender', 'http://www.wikidata.org/entity/Q1052281'), ('glbl', 'transgender female')]
# [('gender', 'http://www.wikidata.org/entity/Q48270'), ('glbl', 'non-binary')]
# 4

# %%
queryString = """
SELECT ?flbl ?dir (COUNT(DISTINCT ?worker) AS ?num_work) ?fem_worker ?mal_worker
WHERE { 

{
    # ?film wdt:P31 wd:Q11424 ;
        # ?role ?worker .

    # ?film wdt:P57 wd:Q3772 .

    # ?worker wdt:P31 wd:Q5 ;
            wdt:P569 ?db .
            
    {
        SELECT ?film (COUNT(DISTINCT ?worker) AS ?fem_worker)
        WHERE
        {
            # ?film wdt:P31 wd:Q11424 ;
            # ?role ?worker .

            # ?film wdt:P57 wd:Q3772 .

            # ?worker wdt:P31 wd:Q5 ;
                    wdt:P21 wd:Q6581072 .
        }
        GROUP BY ?film
    }
    
    {
        SELECT ?film (COUNT(DISTINCT ?worker) AS ?mal_worker)
        WHERE
        {
            # ?film wdt:P31 wd:Q11424 ;
            # ?role ?worker .

            # ?film wdt:P57 wd:Q3772 .

            # ?worker wdt:P31 wd:Q5 ;
                    wdt:P21 wd:Q6581097 .
        }
        GROUP BY ?film
    }

    # ?worker <http://schema.org/name> ?wlbl .
    # ?role <http://schema.org/name> ?rlbl .
    # ?film <http://schema.org/name> ?flbl .
    wd:Q3772 <http://schema.org/name> ?dir .
}
UNION
{
    # ?film wdt:P31 wd:Q11424 ;
        # ?role ?worker .

    # ?film wdt:P57 wd:Q25089 .

    # ?worker wdt:P31 wd:Q5 .
    
    {
        SELECT ?film (COUNT(DISTINCT ?worker) AS ?fem_worker)
        WHERE
        {
            # ?film wdt:P31 wd:Q11424 ;
            # ?role ?worker .

            # ?film wdt:P57 wd:Q25089 .

            # ?worker wdt:P31 wd:Q5 ;
                    wdt:P21 wd:Q6581072 .
        }
        GROUP BY ?film
    }
    
    {
        SELECT ?film (COUNT(DISTINCT ?worker) AS ?mal_worker)
        WHERE
        {
            # ?film wdt:P31 wd:Q11424 ;
            # ?role ?worker .

            # ?film wdt:P57 wd:Q25089 .

            # ?worker wdt:P31 wd:Q5 ;
                    wdt:P21 wd:Q6581097 .
        }
        GROUP BY ?film
    }

    # ?worker <http://schema.org/name> ?wlbl .
    # ?role <http://schema.org/name> ?rlbl .
    # ?film <http://schema.org/name> ?flbl .
    wd:Q25089 <http://schema.org/name> ?dir .
}

FILTER (?role != wdt:P57)

} 
GROUP BY ?flbl ?dir ?fem_worker ?mal_worker
ORDER BY ?flbl
LIMIT 40
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('flbl', "A Midsummer Night's Sex Comedy"), ('dir', 'Woody Allen'), ('num_work', '11'), ('fem_worker', '4'), ('mal_worker', '7')]
# [('flbl', 'A Rainy Day in New York'), ('dir', 'Woody Allen'), ('num_work', '15'), ('fem_worker', '9'), ('mal_worker', '6')]
# [('flbl', 'Alice'), ('dir', 'Woody Allen'), ('num_work', '35'), ('fem_worker', '18'), ('mal_worker', '17')]
# [('flbl', 'Annie Hall'), ('dir', 'Woody Allen'), ('num_work', '38'), ('fem_worker', '12'), ('mal_worker', '26')]
# [('flbl', 'Another Woman'), ('dir', 'Woody Allen'), ('num_work', '26'), ('fem_worker', '11'), ('mal_worker', '15')]
# [('flbl', 'Anything Else'), ('dir', 'Woody Allen'), ('num_work', '13'), ('fem_worker', '6'), ('mal_worker', '7')]
# [('flbl', 'Bananas'), ('dir', 'Woody Allen'), ('num_work', '21'), ('fem_worker', '4'), ('mal_worker', '17')]
# [('flbl', 'Blue Jasmine'), ('dir', 'Woody Allen'), ('num_work', '21'), ('fem_worker', '5'), ('mal_worker', '16')]
# [('flbl', 'Broadway Danny Rose'), ('dir', 'Woody Allen'), ('num_work', '20'), ('fem_worker', '3'), ('mal_worker', '17')]
# [('flbl', 'Bullets Over Broadway'), ('dir', 'Woody Allen'), ('num_work', '38'), ('fem_worker', '16'), ('mal_worker', '22')]
# [('flbl', 'Café Society'), ('dir', 'Woody Allen'), ('num_work', '20'), ('fem_worker', '8'), ('mal_worker', '12')]
# [('flbl', "Cassandra's Dream"), ('dir', 'Woody Allen'), ('num_work', '22'), ('fem_worker', '7'), ('mal_worker', '15')]
# [('flbl', 'Celebrity'), ('dir', 'Woody Allen'), ('num_work', '74'), ('fem_worker', '33'), ('mal_worker', '41')]
# [('flbl', 'Crimes and Misdemeanors'), ('dir', 'Woody Allen'), ('num_work', '29'), ('fem_worker', '14'), ('mal_worker', '15')]
# [('flbl', 'Death Proof'), ('dir', 'Quentin Tarantino'), ('num_work', '24'), ('fem_worker', '12'), ('mal_worker', '11')]
# [('flbl', 'Deconstructing Harry'), ('dir', 'Woody Allen'), ('num_work', '41'), ('fem_worker', '17'), ('mal_worker', '24')]
# [('flbl', 'Django Unchained'), ('dir', 'Quentin Tarantino'), ('num_work', '61'), ('fem_worker', '12'), ('mal_worker', '50')]
# [('flbl', 'Everyone Says I Love You'), ('dir', 'Woody Allen'), ('num_work', '27'), ('fem_worker', '9'), ('mal_worker', '18')]
# [('flbl', 'Everything You Always Wanted to Know About Sex*'), ('dir', 'Woody Allen'), ('num_work', '27'), ('fem_worker', '5'), ('mal_worker', '22')]
# [('flbl', 'Hannah and Her Sisters'), ('dir', 'Woody Allen'), ('num_work', '27'), ('fem_worker', '9'), ('mal_worker', '18')]
# [('flbl', 'Hollywood Ending'), ('dir', 'Woody Allen'), ('num_work', '28'), ('fem_worker', '10'), ('mal_worker', '18')]
# [('flbl', 'Husbands and Wives'), ('dir', 'Woody Allen'), ('num_work', '22'), ('fem_worker', '10'), ('mal_worker', '12')]
# [('flbl', 'Inglourious Basterds'), ('dir', 'Quentin Tarantino'), ('num_work', '60'), ('fem_worker', '11'), ('mal_worker', '49')]
# [('flbl', 'Interiors'), ('dir', 'Woody Allen'), ('num_work', '14'), ('fem_worker', '5'), ('mal_worker', '9')]
# [('flbl', 'Irrational Man'), ('dir', 'Woody Allen'), ('num_work', '16'), ('fem_worker', '5'), ('mal_worker', '11')]
# [('flbl', 'Jackie Brown'), ('dir', 'Quentin Tarantino'), ('num_work', '24'), ('fem_worker', '8'), ('mal_worker', '17')]
# [('flbl', 'Kill Bill Volume 1'), ('dir', 'Quentin Tarantino'), ('num_work', '27'), ('fem_worker', '10'), ('mal_worker', '17')]
# [('flbl', 'Kill Bill Volume 2'), ('dir', 'Quentin Tarantino'), ('num_work', '24'), ('fem_worker', '10'), ('mal_worker', '14')]
# [('flbl', 'Kill Bill: The Whole Bloody Affair'), ('dir', 'Quentin Tarantino'), ('num_work', '9'), ('fem_worker', '6'), ('mal_worker', '4')]
# [('flbl', 'Love and Death'), ('dir', 'Woody Allen'), ('num_work', '40'), ('fem_worker', '10'), ('mal_worker', '30')]
# [('flbl', 'Magic in the Moonlight'), ('dir', 'Woody Allen'), ('num_work', '15'), ('fem_worker', '8'), ('mal_worker', '7')]
# [('flbl', 'Manhattan'), ('dir', 'Woody Allen'), ('num_work', '24'), ('fem_worker', '10'), ('mal_worker', '14')]
# [('flbl', 'Manhattan Murder Mystery'), ('dir', 'Woody Allen'), ('num_work', '18'), ('fem_worker', '6'), ('mal_worker', '12')]
# [('flbl', 'Match Point'), ('dir', 'Woody Allen'), ('num_work', '32'), ('fem_worker', '11'), ('mal_worker', '21')]
# [('flbl', 'Melinda and Melinda'), ('dir', 'Woody Allen'), ('num_work', '28'), ('fem_worker', '12'), ('mal_worker', '16')]
# [('flbl', 'Midnight in Paris'), ('dir', 'Woody Allen'), ('num_work', '40'), ('fem_worker', '16'), ('mal_worker', '24')]
# [('flbl', 'Mighty Aphrodite'), ('dir', 'Woody Allen'), ('num_work', '22'), ('fem_worker', '8'), ('mal_worker', '14')]
# [('flbl', 'New York Stories'), ('dir', 'Woody Allen'), ('num_work', '46'), ('fem_worker', '17'), ('mal_worker', '29')]
# [('flbl', 'Once Upon a Time in Hollywood'), ('dir', 'Quentin Tarantino'), ('num_work', '80'), ('fem_worker', '35'), ('mal_worker', '46')]
# [('flbl', 'Pulp Fiction'), ('dir', 'Quentin Tarantino'), ('num_work', '42'), ('fem_worker', '15'), ('mal_worker', '27')]
# 40

# %%
# get average age for each film of Woody Allen
# Note: it is a test about the datatime datatype (birth date)

queryString = """
SELECT ?film (ROUND(AVG(?age)) AS ?avg_age)
WHERE { 

# ?film wdt:P31 wd:Q11424 ;
    # ?role ?worker .

# ?film wdt:P57 wd:Q3772 .

# ?worker wdt:P31 wd:Q5 ;
        wdt:P569 ?db .
            
BIND(YEAR(NOW()) - YEAR(?db) AS ?age)

} 
GROUP BY ?film
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('film', 'http://www.wikidata.org/entity/Q18225084'), ('avg_year', '61')]
# [('film', 'http://www.wikidata.org/entity/Q104123'), ('avg_year', '65')]
# [('film', 'http://www.wikidata.org/entity/Q571032'), ('avg_year', '62')]
# [('film', 'http://www.wikidata.org/entity/Q1137310'), ('avg_year', '55')]
# [('film', 'http://www.wikidata.org/entity/Q72962'), ('avg_year', '69')]
# [('film', 'http://www.wikidata.org/entity/Q928019'), ('avg_year', '62')]
# [('film', 'http://www.wikidata.org/entity/Q47300912'), ('avg_year', '61')]
# [('film', 'http://www.wikidata.org/entity/Q431252'), ('avg_year', '70')]
# [('film', 'http://www.wikidata.org/entity/Q165325'), ('avg_year', '60')]
# [('film', 'http://www.wikidata.org/entity/Q192115'), ('avg_year', '54')]
# [('film', 'http://www.wikidata.org/entity/Q153723'), ('avg_year', '62')]
# [('film', 'http://www.wikidata.org/entity/Q18126825'), ('avg_year', '61')]
# 12

# %%
# get average age for each film of Woody Allen
# Note: it is a test about the datatime datatype (work of period)

queryString = """
SELECT ?film (ROUND(AVG(?year)) AS ?avg_year) (datatype(?wp) AS ?type)
WHERE { 

# ?film wdt:P31 wd:Q11424 ;
    # ?role ?worker .

# ?film wdt:P57 wd:Q3772 .

# ?worker wdt:P31 wd:Q5 ;
        wdt:P2031 ?wp .
            
BIND(YEAR(?wp) AS ?year)

} 
GROUP BY ?film ?wp
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('film', 'http://www.wikidata.org/entity/Q571032'), ('avg_year', '2010'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q18225084'), ('avg_year', '1981'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q47300912'), ('avg_year', '1968'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q153723'), ('avg_year', '2005'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q153723'), ('avg_year', '1996'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q431252'), ('avg_year', '1979'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q47300912'), ('avg_year', '1956'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q47300912'), ('avg_year', '1950'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q104123'), ('avg_year', '1946'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q192115'), ('avg_year', '1979'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q431252'), ('avg_year', '1968'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q47300912'), ('avg_year', '1996'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q1137310'), ('avg_year', '1980'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q431252'), ('avg_year', '1981'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q928019'), ('avg_year', '1980'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q47300912'), ('avg_year', '2001'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q153723'), ('avg_year', '1982'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q47300912'), ('avg_year', '2004'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q928019'), ('avg_year', '1978'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q431252'), ('avg_year', '1967'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q153723'), ('avg_year', '1960'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q928019'), ('avg_year', '1987'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q47300912'), ('avg_year', '2011'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q18126825'), ('avg_year', '1978'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q18126825'), ('avg_year', '1947'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q571032'), ('avg_year', '1982'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q72962'), ('avg_year', '1985'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q153723'), ('avg_year', '2003'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q192115'), ('avg_year', '1977'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q1137310'), ('avg_year', '1960'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q165325'), ('avg_year', '1947'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q1137310'), ('avg_year', '1996'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q104123'), ('avg_year', '1955'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q153723'), ('avg_year', '1972'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q18225084'), ('avg_year', '1946'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q47300912'), ('avg_year', '1982'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q47300912'), ('avg_year', '1960'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q1137310'), ('avg_year', '1995'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q192115'), ('avg_year', '1989'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q18225084'), ('avg_year', '1995'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q47300912'), ('avg_year', '1990'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q571032'), ('avg_year', '1977'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q571032'), ('avg_year', '1990'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q153723'), ('avg_year', '1991'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q18126825'), ('avg_year', '1995'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q153723'), ('avg_year', '1983'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q571032'), ('avg_year', '1962'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q72962'), ('avg_year', '1987'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q153723'), ('avg_year', '1942'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q928019'), ('avg_year', '1995'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q18225084'), ('avg_year', '1982'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q18225084'), ('avg_year', '1961'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q153723'), ('avg_year', '1967'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q47300912'), ('avg_year', '1978'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q165325'), ('avg_year', '1971'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q153723'), ('avg_year', '1977'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q571032'), ('avg_year', '2008'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q928019'), ('avg_year', '1966'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q104123'), ('avg_year', '1970'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q165325'), ('avg_year', '1960'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q104123'), ('avg_year', '1980'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q431252'), ('avg_year', '1992'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q153723'), ('avg_year', '1992'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q104123'), ('avg_year', '1983'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q47300912'), ('avg_year', '1955'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q165325'), ('avg_year', '1980'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q571032'), ('avg_year', '1981'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q192115'), ('avg_year', '1991'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q165325'), ('avg_year', '1978'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q192115'), ('avg_year', '1985'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q165325'), ('avg_year', '1985'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q18225084'), ('avg_year', '1972'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q571032'), ('avg_year', '1994'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q192115'), ('avg_year', '1997'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q153723'), ('avg_year', '1980'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q571032'), ('avg_year', '1973'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q104123'), ('avg_year', '1992'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q571032'), ('avg_year', '1948'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q431252'), ('avg_year', '1970'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q928019'), ('avg_year', '1989'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q571032'), ('avg_year', '1996'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q431252'), ('avg_year', '1983'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q104123'), ('avg_year', '1981'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q153723'), ('avg_year', '1981'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q571032'), ('avg_year', '1989'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q165325'), ('avg_year', '1988'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q192115'), ('avg_year', '2005'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q928019'), ('avg_year', '1972'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q47300912'), ('avg_year', '1947'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q431252'), ('avg_year', '1984'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q928019'), ('avg_year', '1990'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q431252'), ('avg_year', '1960'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q928019'), ('avg_year', '1973'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q18225084'), ('avg_year', '1989'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q72962'), ('avg_year', '1967'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q431252'), ('avg_year', '1987'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q72962'), ('avg_year', '1983'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q104123'), ('avg_year', '1982'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q192115'), ('avg_year', '1982'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q18225084'), ('avg_year', '1976'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q1137310'), ('avg_year', '2002'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q104123'), ('avg_year', '1990'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q47300912'), ('avg_year', '2014'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q1137310'), ('avg_year', '2001'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q104123'), ('avg_year', '1972'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q104123'), ('avg_year', '1952'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q47300912'), ('avg_year', '1965'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q571032'), ('avg_year', '1970'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q153723'), ('avg_year', '2001'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q104123'), ('avg_year', '1978'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q47300912'), ('avg_year', '1989'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q72962'), ('avg_year', '1982'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q153723'), ('avg_year', '1999'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q104123'), ('avg_year', '1987'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q153723'), ('avg_year', '1951'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q47300912'), ('avg_year', '1961'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q18126825'), ('avg_year', '1982'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q153723'), ('avg_year', '1987'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q571032'), ('avg_year', '1975'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q104123'), ('avg_year', '1985'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q571032'), ('avg_year', '1986'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q165325'), ('avg_year', '1989'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q571032'), ('avg_year', '1985'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q1137310'), ('avg_year', '1989'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q18225084'), ('avg_year', '1985'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q153723'), ('avg_year', '1997'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q47300912'), ('avg_year', '1962'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q1137310'), ('avg_year', '1997'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q47300912'), ('avg_year', '1934'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q1137310'), ('avg_year', '1983'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q165325'), ('avg_year', '1991'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q571032'), ('avg_year', '1979'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q47300912'), ('avg_year', '1964'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q192115'), ('avg_year', '1995'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q104123'), ('avg_year', '1984'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q47300912'), ('avg_year', '1985'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q18126825'), ('avg_year', '1992'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q192115'), ('avg_year', '1987'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q47300912'), ('avg_year', '1994'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q571032'), ('avg_year', '1976'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q928019'), ('avg_year', '1988'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q1137310'), ('avg_year', '1990'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q72962'), ('avg_year', '1970'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q153723'), ('avg_year', '1989'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q928019'), ('avg_year', '1983'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q571032'), ('avg_year', '2001'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q47300912'), ('avg_year', '1999'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q72962'), ('avg_year', '1980'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q192115'), ('avg_year', '1999'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q431252'), ('avg_year', '1985'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q47300912'), ('avg_year', '1995'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q1137310'), ('avg_year', '1961'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q571032'), ('avg_year', '1946'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q928019'), ('avg_year', '1982'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q47300912'), ('avg_year', '1940'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q1137310'), ('avg_year', '1992'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q18225084'), ('avg_year', '1983'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q571032'), ('avg_year', '1971'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q153723'), ('avg_year', '1946'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q571032'), ('avg_year', '2002'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q47300912'), ('avg_year', '1959'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q571032'), ('avg_year', '2004'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q165325'), ('avg_year', '1983'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q928019'), ('avg_year', '1985'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q192115'), ('avg_year', '2006'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q192115'), ('avg_year', '1994'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q104123'), ('avg_year', '1965'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q165325'), ('avg_year', '1982'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q104123'), ('avg_year', '1979'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q165325'), ('avg_year', '1995'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q47300912'), ('avg_year', '2005'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q165325'), ('avg_year', '1976'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q928019'), ('avg_year', '2004'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q192115'), ('avg_year', '1983'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q928019'), ('avg_year', '1960'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q104123'), ('avg_year', '1989'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q72962'), ('avg_year', '1943'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q18225084'), ('avg_year', '1960'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q165325'), ('avg_year', '1973'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q928019'), ('avg_year', '1992'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q153723'), ('avg_year', '1975'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q165325'), ('avg_year', '1990'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q47300912'), ('avg_year', '1983'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q1137310'), ('avg_year', '1973'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q153723'), ('avg_year', '1914'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q18126825'), ('avg_year', '1988'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q192115'), ('avg_year', '1981'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q72962'), ('avg_year', '1979'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q47300912'), ('avg_year', '2006'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q47300912'), ('avg_year', '1953'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q1137310'), ('avg_year', '1993'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q47300912'), ('avg_year', '2007'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q431252'), ('avg_year', '1982'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q153723'), ('avg_year', '1988'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q47300912'), ('avg_year', '1992'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q431252'), ('avg_year', '1973'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q571032'), ('avg_year', '1967'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q104123'), ('avg_year', '1991'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q47300912'), ('avg_year', '2017'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q47300912'), ('avg_year', '1963'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q165325'), ('avg_year', '1992'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q18225084'), ('avg_year', '2010'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q72962'), ('avg_year', '1989'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q431252'), ('avg_year', '1975'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q1137310'), ('avg_year', '1998'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q47300912'), ('avg_year', '1987'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q571032'), ('avg_year', '1997'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q104123'), ('avg_year', '1967'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q153723'), ('avg_year', '2000'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q431252'), ('avg_year', '1963'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q192115'), ('avg_year', '1990'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q1137310'), ('avg_year', '1994'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q18225084'), ('avg_year', '2004'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q165325'), ('avg_year', '1987'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q18225084'), ('avg_year', '1973'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q928019'), ('avg_year', '1965'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q153723'), ('avg_year', '1998'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q192115'), ('avg_year', '1996'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q571032'), ('avg_year', '1974'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q571032'), ('avg_year', '1995'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q571032'), ('avg_year', '1983'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q18126825'), ('avg_year', '1960'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q571032'), ('avg_year', '1978'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q18126825'), ('avg_year', '1983'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q18225084'), ('avg_year', '1977'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q153723'), ('avg_year', '1994'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q431252'), ('avg_year', '1972'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q104123'), ('avg_year', '1969'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q431252'), ('avg_year', '1953'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q192115'), ('avg_year', '1988'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q1137310'), ('avg_year', '1991'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q18126825'), ('avg_year', '1989'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q18225084'), ('avg_year', '1990'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q431252'), ('avg_year', '1991'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q153723'), ('avg_year', '1965'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q431252'), ('avg_year', '1980'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q47300912'), ('avg_year', '1980'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q192115'), ('avg_year', '1992'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q928019'), ('avg_year', '1947'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q104123'), ('avg_year', '1986'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q571032'), ('avg_year', '1980'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q192115'), ('avg_year', '1969'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q153723'), ('avg_year', '2007'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q47300912'), ('avg_year', '1971'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q928019'), ('avg_year', '1991'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q571032'), ('avg_year', '1972'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q571032'), ('avg_year', '1960'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q18126825'), ('avg_year', '1985'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q47300912'), ('avg_year', '1993'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# 249

# %%
# get publication year for each film of Woody Allen

queryString = """
SELECT ?film (YEAR(?pub_year) AS ?pub_y) (datatype(?pub_year) AS ?type)
WHERE { 

# ?film wdt:P31 wd:Q11424 .

# ?film wdt:P57 wd:Q3772 .
    
OPTIONAL { ?film wdt:P577 ?pub_year }

} 
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('film', 'http://www.wikidata.org/entity/Q18225084'), ('pub_y', '2015'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q18225084'), ('pub_y', '2016'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q18225084'), ('pub_y', '2016'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q104123'), ('pub_y', '1994'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q104123'), ('pub_y', '1994'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q104123'), ('pub_y', '1994'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q1137310'), ('pub_y', '2007'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q1137310'), ('pub_y', '2007'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q1137310'), ('pub_y', '2007'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q192115'), ('pub_y', '2005'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q192115'), ('pub_y', '2005'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q192115'), ('pub_y', '2005'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q165325'), ('pub_y', '2003'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q165325'), ('pub_y', '2003'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q431252'), ('pub_y', '1997'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q431252'), ('pub_y', '1997'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q431252'), ('pub_y', '1998'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q153723'), ('pub_y', '2009'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q153723'), ('pub_y', '2009'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q153723'), ('pub_y', '2009'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q72962'), ('pub_y', '1992'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q72962'), ('pub_y', '1992'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q928019'), ('pub_y', '2004'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q928019'), ('pub_y', '2004'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q571032'), ('pub_y', '2012'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q571032'), ('pub_y', '2013'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q47300912'), ('pub_y', '2019'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# [('film', 'http://www.wikidata.org/entity/Q18126825'), ('pub_y', '2003'), ('type', 'http://www.w3.org/2001/XMLSchema#dateTime')]
# 28

# %%
# GOAL (4)
# get information about each film of Woody Allen and Quentin Tarantino
# 
# Data:
# - film name
# - director
# - number of workers
# - female workers
# - male workers
# - age average
# - work period start


queryString = """
SELECT ?flbl ?dir (COUNT(DISTINCT ?worker) AS ?num_work) ?fem_worker ?mal_worker (ROUND(AVG(?age)) AS ?avg_age) (ROUND(AVG(?wp_year)) AS ?avg_work_period)
WHERE { 

{
    # ?film wdt:P31 wd:Q11424 ;
        # ?role ?worker .

    # ?film wdt:P57 wd:Q3772 ;
        wdt:P577 ?pub_year .

    # ?worker wdt:P31 wd:Q5 ;
            wdt:P569 ?db ;
            wdt:P2031 ?wp .
    {
        SELECT ?film (COUNT(DISTINCT ?worker) AS ?fem_worker)
        WHERE
        {
            # ?film wdt:P31 wd:Q11424 ;
            # ?role ?worker .

            # ?film wdt:P57 wd:Q3772 .

            # ?worker wdt:P31 wd:Q5 ;
                    wdt:P21 wd:Q6581072 .
        }
        GROUP BY ?film
    }
    
    {
        SELECT ?film (COUNT(DISTINCT ?worker) AS ?mal_worker)
        WHERE
        {
            # ?film wdt:P31 wd:Q11424 ;
            # ?role ?worker .

            # ?film wdt:P57 wd:Q3772 .

            # ?worker wdt:P31 wd:Q5 ;
                    wdt:P21 wd:Q6581097 .
        }
        GROUP BY ?film
    }

    # ?worker <http://schema.org/name> ?wlbl .
    # ?role <http://schema.org/name> ?rlbl .
    # ?film <http://schema.org/name> ?flbl .
    wd:Q3772 <http://schema.org/name> ?dir .
    
    BIND(YEAR(?pub_year) - YEAR(?db) AS ?age) 
    BIND(YEAR(?wp) AS ?wp_year)
    
}
UNION
{
    # ?film wdt:P31 wd:Q11424 ;
        # ?role ?worker .

    # ?film wdt:P57 wd:Q25089 ;
        wdt:P577 ?pub_year .

    # ?worker wdt:P31 wd:Q5 ;
            wdt:P569 ?db ;
            wdt:P2031 ?wp .
            
    
    {
        SELECT ?film (COUNT(DISTINCT ?worker) AS ?fem_worker)
        WHERE
        {
            # ?film wdt:P31 wd:Q11424 ;
            # ?role ?worker .

            # ?film wdt:P57 wd:Q25089 .

            # ?worker wdt:P31 wd:Q5 ;
                    wdt:P21 wd:Q6581072 .
        }
        GROUP BY ?film
    }
    
    {
        SELECT ?film (COUNT(DISTINCT ?worker) AS ?mal_worker)
        WHERE
        {
            # ?film wdt:P31 wd:Q11424 ;
            # ?role ?worker .

            # ?film wdt:P57 wd:Q25089 .

            # ?worker wdt:P31 wd:Q5 ;
                    wdt:P21 wd:Q6581097 .
        }
        GROUP BY ?film
    }

    # ?worker <http://schema.org/name> ?wlbl .
    # ?role <http://schema.org/name> ?rlbl .
    # ?film <http://schema.org/name> ?flbl .
    wd:Q25089 <http://schema.org/name> ?dir .
    
    
    BIND(YEAR(?pub_year) - YEAR(?db) AS ?age) 
    BIND(YEAR(?wp) AS ?wp_year)
    
}

FILTER (?role != wdt:P57)

} 
GROUP BY ?flbl ?dir ?fem_worker ?mal_worker
ORDER BY ?flbl
LIMIT 50
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('flbl', "A Midsummer Night's Sex Comedy"), ('dir', 'Woody Allen'), ('num_work', '10'), ('fem_worker', '4'), ('mal_worker', '7'), ('avg_age', '56'), ('avg_work_period', '1948')]
# [('flbl', 'A Rainy Day in New York'), ('dir', 'Woody Allen'), ('num_work', '13'), ('fem_worker', '9'), ('mal_worker', '6'), ('avg_age', '47'), ('avg_work_period', '1990')]
# [('flbl', 'Alice'), ('dir', 'Woody Allen'), ('num_work', '29'), ('fem_worker', '18'), ('mal_worker', '17'), ('avg_age', '47'), ('avg_work_period', '1968')]
# [('flbl', 'Annie Hall'), ('dir', 'Woody Allen'), ('num_work', '25'), ('fem_worker', '12'), ('mal_worker', '26'), ('avg_age', '40'), ('avg_work_period', '1961')]
# [('flbl', 'Another Woman'), ('dir', 'Woody Allen'), ('num_work', '21'), ('fem_worker', '11'), ('mal_worker', '15'), ('avg_age', '47'), ('avg_work_period', '1965')]
# [('flbl', 'Anything Else'), ('dir', 'Woody Allen'), ('num_work', '12'), ('fem_worker', '6'), ('mal_worker', '7'), ('avg_age', '46'), ('avg_work_period', '1980')]
# [('flbl', 'Bananas'), ('dir', 'Woody Allen'), ('num_work', '16'), ('fem_worker', '4'), ('mal_worker', '17'), ('avg_age', '38'), ('avg_work_period', '1959')]
# [('flbl', 'Blue Jasmine'), ('dir', 'Woody Allen'), ('num_work', '18'), ('fem_worker', '5'), ('mal_worker', '16'), ('avg_age', '48'), ('avg_work_period', '1989')]
# [('flbl', 'Broadway Danny Rose'), ('dir', 'Woody Allen'), ('num_work', '12'), ('fem_worker', '3'), ('mal_worker', '17'), ('avg_age', '51'), ('avg_work_period', '1957')]
# [('flbl', 'Bullets Over Broadway'), ('dir', 'Woody Allen'), ('num_work', '25'), ('fem_worker', '16'), ('mal_worker', '22'), ('avg_age', '48'), ('avg_work_period', '1974')]
# [('flbl', 'Café Society'), ('dir', 'Woody Allen'), ('num_work', '17'), ('fem_worker', '8'), ('mal_worker', '12'), ('avg_age', '55'), ('avg_work_period', '1984')]
# [('flbl', "Cassandra's Dream"), ('dir', 'Woody Allen'), ('num_work', '18'), ('fem_worker', '7'), ('mal_worker', '15'), ('avg_age', '50'), ('avg_work_period', '1982')]
# [('flbl', 'Celebrity'), ('dir', 'Woody Allen'), ('num_work', '51'), ('fem_worker', '33'), ('mal_worker', '41'), ('avg_age', '45'), ('avg_work_period', '1978')]
# [('flbl', 'Crimes and Misdemeanors'), ('dir', 'Woody Allen'), ('num_work', '25'), ('fem_worker', '14'), ('mal_worker', '15'), ('avg_age', '56'), ('avg_work_period', '1961')]
# [('flbl', 'Death Proof'), ('dir', 'Quentin Tarantino'), ('num_work', '22'), ('fem_worker', '12'), ('mal_worker', '11'), ('avg_age', '40'), ('avg_work_period', '1988')]
# [('flbl', 'Deconstructing Harry'), ('dir', 'Woody Allen'), ('num_work', '40'), ('fem_worker', '17'), ('mal_worker', '24'), ('avg_age', '47'), ('avg_work_period', '1974')]
# [('flbl', 'Django Unchained'), ('dir', 'Quentin Tarantino'), ('num_work', '47'), ('fem_worker', '12'), ('mal_worker', '50'), ('avg_age', '53'), ('avg_work_period', '1981')]
# [('flbl', 'Everyone Says I Love You'), ('dir', 'Woody Allen'), ('num_work', '23'), ('fem_worker', '9'), ('mal_worker', '18'), ('avg_age', '39'), ('avg_work_period', '1978')]
# [('flbl', 'Everything You Always Wanted to Know About Sex*'), ('dir', 'Woody Allen'), ('num_work', '16'), ('fem_worker', '5'), ('mal_worker', '22'), ('avg_age', '45'), ('avg_work_period', '1954')]
# [('flbl', 'Hannah and Her Sisters'), ('dir', 'Woody Allen'), ('num_work', '25'), ('fem_worker', '9'), ('mal_worker', '18'), ('avg_age', '54'), ('avg_work_period', '1956')]
# [('flbl', 'Hollywood Ending'), ('dir', 'Woody Allen'), ('num_work', '18'), ('fem_worker', '10'), ('mal_worker', '18'), ('avg_age', '50'), ('avg_work_period', '1976')]
# [('flbl', 'Husbands and Wives'), ('dir', 'Woody Allen'), ('num_work', '15'), ('fem_worker', '10'), ('mal_worker', '12'), ('avg_age', '49'), ('avg_work_period', '1968')]
# [('flbl', 'Inglourious Basterds'), ('dir', 'Quentin Tarantino'), ('num_work', '37'), ('fem_worker', '11'), ('mal_worker', '49'), ('avg_age', '49'), ('avg_work_period', '1982')]
# [('flbl', 'Interiors'), ('dir', 'Woody Allen'), ('num_work', '10'), ('fem_worker', '5'), ('mal_worker', '9'), ('avg_age', '43'), ('avg_work_period', '1961')]
# [('flbl', 'Irrational Man'), ('dir', 'Woody Allen'), ('num_work', '13'), ('fem_worker', '5'), ('mal_worker', '11'), ('avg_age', '51'), ('avg_work_period', '1988')]
# [('flbl', 'Jackie Brown'), ('dir', 'Quentin Tarantino'), ('num_work', '22'), ('fem_worker', '8'), ('mal_worker', '17'), ('avg_age', '46'), ('avg_work_period', '1976')]
# [('flbl', 'Kill Bill Volume 1'), ('dir', 'Quentin Tarantino'), ('num_work', '23'), ('fem_worker', '10'), ('mal_worker', '17'), ('avg_age', '43'), ('avg_work_period', '1981')]
# [('flbl', 'Kill Bill Volume 2'), ('dir', 'Quentin Tarantino'), ('num_work', '23'), ('fem_worker', '10'), ('mal_worker', '14'), ('avg_age', '44'), ('avg_work_period', '1982')]
# [('flbl', 'Kill Bill: The Whole Bloody Affair'), ('dir', 'Quentin Tarantino'), ('num_work', '9'), ('fem_worker', '6'), ('mal_worker', '4'), ('avg_age', '43'), ('avg_work_period', '1980')]
# [('flbl', 'Love and Death'), ('dir', 'Woody Allen'), ('num_work', '18'), ('fem_worker', '10'), ('mal_worker', '30'), ('avg_age', '44'), ('avg_work_period', '1956')]
# [('flbl', 'Magic in the Moonlight'), ('dir', 'Woody Allen'), ('num_work', '14'), ('fem_worker', '8'), ('mal_worker', '7'), ('avg_age', '56'), ('avg_work_period', '1982')]
# [('flbl', 'Manhattan'), ('dir', 'Woody Allen'), ('num_work', '16'), ('fem_worker', '10'), ('mal_worker', '14'), ('avg_age', '38'), ('avg_work_period', '1965')]
# [('flbl', 'Manhattan Murder Mystery'), ('dir', 'Woody Allen'), ('num_work', '15'), ('fem_worker', '6'), ('mal_worker', '12'), ('avg_age', '49'), ('avg_work_period', '1970')]
# [('flbl', 'Match Point'), ('dir', 'Woody Allen'), ('num_work', '23'), ('fem_worker', '11'), ('mal_worker', '21'), ('avg_age', '46'), ('avg_work_period', '1981')]
# [('flbl', 'Melinda and Melinda'), ('dir', 'Woody Allen'), ('num_work', '23'), ('fem_worker', '12'), ('mal_worker', '16'), ('avg_age', '57'), ('avg_work_period', '1970')]
# [('flbl', 'Midnight in Paris'), ('dir', 'Woody Allen'), ('num_work', '21'), ('fem_worker', '16'), ('mal_worker', '24'), ('avg_age', '43'), ('avg_work_period', '1991')]
# [('flbl', 'Mighty Aphrodite'), ('dir', 'Woody Allen'), ('num_work', '18'), ('fem_worker', '8'), ('mal_worker', '14'), ('avg_age', '50'), ('avg_work_period', '1967')]
# [('flbl', 'New York Stories'), ('dir', 'Woody Allen'), ('num_work', '37'), ('fem_worker', '17'), ('mal_worker', '29'), ('avg_age', '42'), ('avg_work_period', '1970')]
# [('flbl', 'Once Upon a Time in Hollywood'), ('dir', 'Quentin Tarantino'), ('num_work', '56'), ('fem_worker', '35'), ('mal_worker', '46'), ('avg_age', '55'), ('avg_work_period', '1983')]
# [('flbl', 'Pulp Fiction'), ('dir', 'Quentin Tarantino'), ('num_work', '34'), ('fem_worker', '15'), ('mal_worker', '27'), ('avg_age', '37'), ('avg_work_period', '1979')]
# [('flbl', 'Radio Days'), ('dir', 'Woody Allen'), ('num_work', '29'), ('fem_worker', '8'), ('mal_worker', '26'), ('avg_age', '42'), ('avg_work_period', '1970')]
# [('flbl', 'Reservoir Dogs'), ('dir', 'Quentin Tarantino'), ('num_work', '11'), ('fem_worker', '2'), ('mal_worker', '17'), ('avg_age', '39'), ('avg_work_period', '1977')]
# [('flbl', "Rifkin's Festival"), ('dir', 'Woody Allen'), ('num_work', '9'), ('fem_worker', '4'), ('mal_worker', '7'), ('avg_age', '64'), ('avg_work_period', '1978')]
# [('flbl', 'September'), ('dir', 'Woody Allen'), ('num_work', '11'), ('fem_worker', '5'), ('mal_worker', '7'), ('avg_age', '54'), ('avg_work_period', '1957')]
# [('flbl', 'Shadows and Fog'), ('dir', 'Woody Allen'), ('num_work', '33'), ('fem_worker', '10'), ('mal_worker', '30'), ('avg_age', '45'), ('avg_work_period', '1971')]
# [('flbl', 'Sin City'), ('dir', 'Quentin Tarantino'), ('num_work', '31'), ('fem_worker', '14'), ('mal_worker', '25'), ('avg_age', '36'), ('avg_work_period', '1990')]
# [('flbl', 'Sleeper'), ('dir', 'Woody Allen'), ('num_work', '10'), ('fem_worker', '2'), ('mal_worker', '15'), ('avg_age', '50'), ('avg_work_period', '1949')]
# [('flbl', 'Small Time Crooks'), ('dir', 'Woody Allen'), ('num_work', '12'), ('fem_worker', '5'), ('mal_worker', '12'), ('avg_age', '53'), ('avg_work_period', '1970')]
# [('flbl', 'Stardust Memories'), ('dir', 'Woody Allen'), ('num_work', '21'), ('fem_worker', '13'), ('mal_worker', '16'), ('avg_age', '39'), ('avg_work_period', '1968')]
# [('flbl', 'Sweet and Lowdown'), ('dir', 'Woody Allen'), ('num_work', '16'), ('fem_worker', '8'), ('mal_worker', '16'), ('avg_age', '42'), ('avg_work_period', '1979')]
# 50

# %% [markdown]
# ## Task 5

# %%
# GOAL (5)
# get comparison between Woody Allen and Quentin Tarantino
# 
# Data:
# - director
# - birth date
# - work period start
# - number of films
# - number of awards
# - number of nominations
# - number of shared workers
# - name of most frequent worker
# - frequence

queryString = """
SELECT DISTINCT ?dir (?db AS ?birth_date) (?wp_year AS ?start_work) (COUNT(DISTINCT ?film) AS ?num_films) (COUNT(DISTINCT ?aw) AS ?awards) (COUNT(DISTINCT ?nom_for) AS ?nominations) (COUNT(DISTINCT ?worker) AS ?shared_w)
                # ?fwlbl ?freq
WHERE { 

{
    wd:Q3772 wdt:P569 ?db ;
            wdt:P2031 ?wp ;
            wdt:P1411 ?nom_for ;
            wdt:P166 ?aw .
    
    # ?film wdt:P31 wd:Q11424 ;
        # ?role ?worker .

    # ?film wdt:P57 wd:Q3772 .

    # ?worker wdt:P31 wd:Q5 .
            
    
    # ?role <http://schema.org/name> ?rlbl .
    # ?film <http://schema.org/name> ?flbl .
    wd:Q3772 <http://schema.org/name> ?dir .
    
    BIND(YEAR(?wp) AS ?wp_year)
    
    {
        SELECT DISTINCT ?worker
        WHERE {
        
            # ?film wdt:P31 wd:Q11424 ;
                # ?role ?worker .

            # ?film wdt:P57 wd:Q25089 .

            # ?worker wdt:P31 wd:Q5 .
            
            FILTER (?role != wdt:P57)
        
        }
    }
    
    {
        SELECT (?worker AS ?freq_worker) ?fwlbl (COUNT(?worker) AS ?freq)
        WHERE {
        
            # ?film wdt:P31 wd:Q11424 ;
                # ?role ?worker .

            # ?film wdt:P57 wd:Q3772 .

            # ?worker wdt:P31 wd:Q5 .
        
            # ?worker <http://schema.org/name> ?fwlbl .
            
            FILTER (?worker != wd:Q3772)
        }
        GROUP BY ?worker ?fwlbl
        ORDER BY DESC (?freq)
        LIMIT 1
    }
}
UNION
{
    wd:Q25089 wdt:P569 ?db ;
            wdt:P2031 ?wp ;
            wdt:P1411 ?nom_for ;
            wdt:P166 ?aw .
    
    # ?film wdt:P31 wd:Q11424 ;
        # ?role ?worker .

    # ?film wdt:P57 wd:Q25089 .

    # ?worker wdt:P31 wd:Q5 .
            
    # ?role <http://schema.org/name> ?rlbl .
    # ?film <http://schema.org/name> ?flbl .
    wd:Q25089 <http://schema.org/name> ?dir .
     
    BIND(YEAR(?wp) AS ?wp_year)
    
    {
        SELECT DISTINCT ?worker
        WHERE {
        
            # ?film wdt:P31 wd:Q11424 ;
                # ?role ?worker .

            # ?film wdt:P57 wd:Q3772 .

            # ?worker wdt:P31 wd:Q5 .
        
        }
    }
    
    {
        SELECT (?worker AS ?freq_worker) ?fwlbl (COUNT(?worker) AS ?freq)
        WHERE {
        
            # ?film wdt:P31 wd:Q11424 ;
                # ?role ?worker .

            # ?film wdt:P57 wd:Q25089 .

            # ?worker wdt:P31 wd:Q5 .
        
            # ?worker <http://schema.org/name> ?fwlbl .
            
            FILTER (?worker != wd:Q25089)
        }
        GROUP BY ?worker ?fwlbl
        ORDER BY DESC (?freq)
        LIMIT 1
    }
    
}

FILTER (?role != wdt:P57)

} 
GROUP BY ?dir ?db ?wp_year ?fwlbl ?freq
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('dir', 'Quentin Tarantino'), ('birth_date', '1963-03-27T00:00:00Z'), ('start_work', '1983'), ('num_films', '11'), ('awards', '16'), ('nominations', '4'), ('shared_w', '16'), ('fwlbl', 'Lawrence Bender'), ('freq', '10')]
# [('dir', 'Woody Allen'), ('birth_date', '1935-12-01T00:00:00Z'), ('start_work', '1950'), ('num_films', '14'), ('awards', '32'), ('nominations', '4'), ('shared_w', '16'), ('fwlbl', 'Letty Aronson'), ('freq', '22')]
# 2

# %% [markdown]
# ## Task 6

# %%
# get predicates from Woody Allen's films

queryString = """
SELECT DISTINCT ?p ?plbl
WHERE { 

# ?film wdt:P31 wd:Q11424 ;
    wdt:P57 wd:Q3772 ;
    # ?p ?o .
    
# ?p <http://schema.org/name> ?plbl .

FILTER (!CONTAINS (?plbl, "ID") && !CONTAINS (?plbl, "username") && !CONTAINS (?plbl, "code"))

} 
ORDER BY ?plbl
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P8895'), ('plbl', 'All the Tropes identifier')]
# [('p', 'http://www.wikidata.org/prop/direct/P2629'), ('plbl', 'BBFC rating')]
# [('p', 'http://www.wikidata.org/prop/direct/P2758'), ('plbl', 'CNC film rating (France)')]
# [('p', 'http://www.wikidata.org/prop/direct/P3402'), ('plbl', 'CNC film rating (Romania)')]
# [('p', 'http://www.wikidata.org/prop/direct/P4276'), ('plbl', 'Cinémathèque québécoise work identifier')]
# [('p', 'http://www.wikidata.org/prop/direct/P3216'), ('plbl', 'ClassInd rating')]
# [('p', 'http://www.wikidata.org/prop/direct/P373'), ('plbl', 'Commons category')]
# [('p', 'http://www.wikidata.org/prop/direct/P2756'), ('plbl', 'EIRIN film rating')]
# [('p', 'http://www.wikidata.org/prop/direct/P4437'), ('plbl', 'FPB rating')]
# [('p', 'http://www.wikidata.org/prop/direct/P1981'), ('plbl', 'FSK film rating')]
# [('p', 'http://www.wikidata.org/prop/direct/P2747'), ('plbl', 'Filmiroda rating')]
# [('p', 'http://www.wikidata.org/prop/direct/P3306'), ('plbl', 'ICAA rating')]
# [('p', 'http://www.wikidata.org/prop/direct/P7573'), ('plbl', 'IFCO rating')]
# [('p', 'http://www.wikidata.org/prop/direct/P5150'), ('plbl', 'IGAC rating')]
# [('p', 'http://www.wikidata.org/prop/direct/P5201'), ('plbl', 'IMDA rating')]
# [('p', 'http://www.wikidata.org/prop/direct/P3212'), ('plbl', 'ISAN')]
# [('p', 'http://www.wikidata.org/prop/direct/P3650'), ('plbl', 'JMK film rating')]
# [('p', 'http://www.wikidata.org/prop/direct/P2684'), ('plbl', 'Kijkwijzer rating')]
# [('p', 'http://www.wikidata.org/prop/direct/P1657'), ('plbl', 'MPAA film rating')]
# [('p', 'http://www.wikidata.org/prop/direct/P8889'), ('plbl', 'MTRCB rating')]
# [('p', 'http://www.wikidata.org/prop/direct/P5970'), ('plbl', 'Medierådet rating')]
# [('p', 'http://www.wikidata.org/prop/direct/P2363'), ('plbl', 'NMHH film rating')]
# [('p', 'http://www.wikidata.org/prop/direct/P6658'), ('plbl', 'RCQ classification')]
# [('p', 'http://www.wikidata.org/prop/direct/P3834'), ('plbl', 'RTC film rating')]
# [('p', 'http://www.wikidata.org/prop/direct/P6839'), ('plbl', 'TV Tropes identifier')]
# [('p', 'http://www.wikidata.org/prop/direct/P1877'), ('plbl', 'after a work by')]
# [('p', 'http://www.wikidata.org/prop/direct/P2061'), ('plbl', 'aspect ratio')]
# [('p', 'http://www.wikidata.org/prop/direct/P5021'), ('plbl', 'assessment')]
# [('p', 'http://www.wikidata.org/prop/direct/P166'), ('plbl', 'award received')]
# [('p', 'http://www.wikidata.org/prop/direct/P144'), ('plbl', 'based on')]
# [('p', 'http://www.wikidata.org/prop/direct/P2142'), ('plbl', 'box office')]
# [('p', 'http://www.wikidata.org/prop/direct/P161'), ('plbl', 'cast member')]
# [('p', 'http://www.wikidata.org/prop/direct/P674'), ('plbl', 'characters')]
# [('p', 'http://www.wikidata.org/prop/direct/P195'), ('plbl', 'collection')]
# [('p', 'http://www.wikidata.org/prop/direct/P462'), ('plbl', 'color')]
# [('p', 'http://www.wikidata.org/prop/direct/P86'), ('plbl', 'composer')]
# [('p', 'http://www.wikidata.org/prop/direct/P2130'), ('plbl', 'cost')]
# [('p', 'http://www.wikidata.org/prop/direct/P2515'), ('plbl', 'costume designer')]
# [('p', 'http://www.wikidata.org/prop/direct/P495'), ('plbl', 'country of origin')]
# [('p', 'http://www.wikidata.org/prop/direct/P4969'), ('plbl', 'derivative work')]
# [('p', 'http://www.wikidata.org/prop/direct/P1889'), ('plbl', 'different from')]
# [('p', 'http://www.wikidata.org/prop/direct/P57'), ('plbl', 'director')]
# [('p', 'http://www.wikidata.org/prop/direct/P344'), ('plbl', 'director of photography')]
# [('p', 'http://www.wikidata.org/prop/direct/P750'), ('plbl', 'distributed by')]
# [('p', 'http://www.wikidata.org/prop/direct/P437'), ('plbl', 'distribution format')]
# [('p', 'http://www.wikidata.org/prop/direct/P2047'), ('plbl', 'duration')]
# [('p', 'http://www.wikidata.org/prop/direct/P1431'), ('plbl', 'executive producer')]
# [('p', 'http://www.wikidata.org/prop/direct/P2755'), ('plbl', 'exploitation visa number')]
# [('p', 'http://www.wikidata.org/prop/direct/P1040'), ('plbl', 'film editor')]
# [('p', 'http://www.wikidata.org/prop/direct/P915'), ('plbl', 'filming location')]
# [('p', 'http://www.wikidata.org/prop/direct/P1922'), ('plbl', 'first line')]
# [('p', 'http://www.wikidata.org/prop/direct/P156'), ('plbl', 'followed by')]
# [('p', 'http://www.wikidata.org/prop/direct/P136'), ('plbl', 'genre')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('plbl', 'has part')]
# [('p', 'http://www.wikidata.org/prop/direct/P18'), ('plbl', 'image')]
# [('p', 'http://www.wikidata.org/prop/direct/P941'), ('plbl', 'inspired by')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('plbl', 'instance of')]
# [('p', 'http://www.wikidata.org/prop/direct/P154'), ('plbl', 'logo image')]
# [('p', 'http://www.wikidata.org/prop/direct/P921'), ('plbl', 'main subject')]
# [('p', 'http://www.wikidata.org/prop/direct/P840'), ('plbl', 'narrative location')]
# [('p', 'http://www.wikidata.org/prop/direct/P2438'), ('plbl', 'narrator')]
# [('p', 'http://www.wikidata.org/prop/direct/P1411'), ('plbl', 'nominated for')]
# [('p', 'http://www.wikidata.org/prop/direct/P856'), ('plbl', 'official website')]
# [('p', 'http://www.wikidata.org/prop/direct/P364'), ('plbl', 'original language of film or TV show')]
# [('p', 'http://www.wikidata.org/prop/direct/P361'), ('plbl', 'part of')]
# [('p', 'http://www.wikidata.org/prop/direct/P179'), ('plbl', 'part of the series')]
# [('p', 'http://www.wikidata.org/prop/direct/P175'), ('plbl', 'performer')]
# [('p', 'http://www.wikidata.org/prop/direct/P162'), ('plbl', 'producer')]
# [('p', 'http://www.wikidata.org/prop/direct/P272'), ('plbl', 'production company')]
# [('p', 'http://www.wikidata.org/prop/direct/P2554'), ('plbl', 'production designer')]
# [('p', 'http://www.wikidata.org/prop/direct/P577'), ('plbl', 'publication date')]
# [('p', 'http://www.wikidata.org/prop/direct/P5555'), ('plbl', 'schematic')]
# [('p', 'http://www.wikidata.org/prop/direct/P58'), ('plbl', 'screenwriter')]
# [('p', 'http://www.wikidata.org/prop/direct/P9215'), ('plbl', 'set during recurring event')]
# [('p', 'http://www.wikidata.org/prop/direct/P8411'), ('plbl', 'set in environment')]
# [('p', 'http://www.wikidata.org/prop/direct/P2408'), ('plbl', 'set in period')]
# [('p', 'http://www.wikidata.org/prop/direct/P8687'), ('plbl', 'social media followers')]
# [('p', 'http://www.wikidata.org/prop/direct/P406'), ('plbl', 'soundtrack release')]
# [('p', 'http://www.wikidata.org/prop/direct/P942'), ('plbl', 'theme music')]
# [('p', 'http://www.wikidata.org/prop/direct/P1476'), ('plbl', 'title')]
# [('p', 'http://www.wikidata.org/prop/direct/P910'), ('plbl', "topic's main category")]
# [('p', 'http://www.wikidata.org/prop/direct/P2283'), ('plbl', 'uses')]
# 82

# %%
# get assessments from Quentin Tarantino's films

queryString = """
SELECT DISTINCT ?ass ?albl
WHERE { 

# ?film wdt:P31 wd:Q11424 ;
    wdt:P57 wd:Q3772 ;
    wdt:P5021 ?ass .
    
# ?ass <http://schema.org/name> ?albl .

} 
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('ass', 'http://www.wikidata.org/entity/Q102180036'), ('albl', 'Riz Test')]
# [('ass', 'http://www.wikidata.org/entity/Q104144087'), ('albl', 'Waithe Test')]
# [('ass', 'http://www.wikidata.org/entity/Q104144383'), ('albl', 'Shukla Test')]
# [('ass', 'http://www.wikidata.org/entity/Q104144557'), ('albl', 'Feldman Test')]
# [('ass', 'http://www.wikidata.org/entity/Q104144947'), ('albl', 'Landau Test')]
# [('ass', 'http://www.wikidata.org/entity/Q105776216'), ('albl', 'reverse Bechdel Test')]
# [('ass', 'http://www.wikidata.org/entity/Q4165246'), ('albl', 'Bechdel test')]
# [('ass', 'http://www.wikidata.org/entity/Q85783379'), ('albl', 'Mako Mori test')]
# [('ass', 'http://www.wikidata.org/entity/Q93605402'), ('albl', 'Vito Russo test')]
# [('ass', 'http://www.wikidata.org/entity/Q105640076'), ('albl', 'Topside Test')]
# [('ass', 'http://www.wikidata.org/entity/Q105641628'), ('albl', 'Coates Test')]
# [('ass', 'http://www.wikidata.org/entity/Q105700813'), ('albl', 'Russ Test')]
# [('ass', 'http://www.wikidata.org/entity/Q105701756'), ('albl', 'Tyrion Test')]
# [('ass', 'http://www.wikidata.org/entity/Q105702736'), ('albl', 'Tauriel Test')]
# [('ass', 'http://www.wikidata.org/entity/Q105708928'), ('albl', 'Raleigh Becket Test')]
# [('ass', 'http://www.wikidata.org/entity/Q105729789'), ('albl', 'Celia Imrie Test')]
# [('ass', 'http://www.wikidata.org/entity/Q105816692'), ('albl', 'BubbleGum Test')]
# [('ass', 'http://www.wikidata.org/entity/Q105918665'), ('albl', 'reverse Waithe Test')]
# [('ass', 'http://www.wikidata.org/entity/Q105919675'), ('albl', 'reverse Landau Test')]
# [('ass', 'http://www.wikidata.org/entity/Q107569507'), ('albl', 'the Villalobos test')]
# 20

# %%
# get costs from Quentin Tarantino's films

queryString = """
SELECT DISTINCT ?film ?cost
WHERE { 

# ?film wdt:P31 wd:Q11424 ;
    wdt:P57 wd:Q3772 ;
    wdt:P2130 ?cost .
} 
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('film', 'http://www.wikidata.org/entity/Q18225084'), ('cost', '44000000')]
# [('film', 'http://www.wikidata.org/entity/Q104123'), ('cost', '8000000')]
# [('film', 'http://www.wikidata.org/entity/Q192115'), ('cost', '40000000')]
# [('film', 'http://www.wikidata.org/entity/Q165325'), ('cost', '30000000')]
# [('film', 'http://www.wikidata.org/entity/Q431252'), ('cost', '12000000')]
# [('film', 'http://www.wikidata.org/entity/Q153723'), ('cost', '70000000')]
# [('film', 'http://www.wikidata.org/entity/Q928019'), ('cost', '30000000')]
# [('film', 'http://www.wikidata.org/entity/Q571032'), ('cost', '100000000')]
# 8

# %%
# GOAL (6)
# get the films of each director with highter budget
# ANSWER: YES

queryString = """
SELECT DISTINCT ?dir ?flbl ?cost
WHERE { 

{
    {
        SELECT ?dir ?film ?cost
        WHERE {
            # ?film wdt:P31 wd:Q11424 ;
                wdt:P57 wd:Q3772 ;
                wdt:P2130 ?cost .                
                
            wd:Q3772 <http://schema.org/name> ?dir .
        }
        ORDER BY DESC (?cost)
        LIMIT 1
    }
    
    # ?film <http://schema.org/name> ?flbl .
}
UNION
{        
    {
        SELECT ?dir ?film ?cost
        WHERE {
            # ?film wdt:P31 wd:Q11424 ;
                wdt:P57 wd:Q25089 ;
                wdt:P2130 ?cost .
                
            wd:Q25089 <http://schema.org/name> ?dir .
        }
        ORDER BY DESC (?cost)
        LIMIT 1
    }
    
    # ?film <http://schema.org/name> ?flbl .
}

} 
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('dir', 'Quentin Tarantino'), ('flbl', 'Django Unchained'), ('cost', '100000000')]
# [('dir', 'Woody Allen'), ('flbl', 'You Will Meet a Tall Dark Stranger'), ('cost', '22000000')]
# 2

# %% [markdown]
# ## Task 7.3

# %%
# GOAL (7.3) PART 1
# get award for Quentin Tarantino's films

queryString = """
SELECT DISTINCT ?aw ?awlbl
WHERE { 

# ?film wdt:P31 wd:Q11424 ;
    wdt:P57 wd:Q3772 ;
    wdt:P166 ?aw .
    
# ?aw <http://schema.org/name> ?awlbl .

} 
ORDER BY ?awlbl
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('aw', 'http://www.wikidata.org/entity/Q277751'), ('awlbl', 'Academy Award for Best Production Design')]
# [('aw', 'http://www.wikidata.org/entity/Q488651'), ('awlbl', 'Academy Award for Best Original Score')]
# [('aw', 'http://www.wikidata.org/entity/Q41417'), ('awlbl', 'Academy Award for Best Writing, Original Screenplay')]
# [('aw', 'http://www.wikidata.org/entity/Q106291'), ('awlbl', 'Academy Award for Best Supporting Actor')]
# [('aw', 'http://www.wikidata.org/entity/Q41375'), ('awlbl', 'BAFTA Award for Best Original Screenplay')]
# [('aw', 'http://www.wikidata.org/entity/Q548389'), ('awlbl', 'BAFTA Award for Best Actor in a Supporting Role')]
# [('aw', 'http://www.wikidata.org/entity/Q3404523'), ('awlbl', 'David di Donatello for Best Foreign Actor')]
# [('aw', 'http://www.wikidata.org/entity/Q849124'), ('awlbl', 'Golden Globe Award for Best Screenplay')]
# [('aw', 'http://www.wikidata.org/entity/Q1170507'), ('awlbl', 'Independent Spirit Award for Best Screenplay')]
# [('aw', 'http://www.wikidata.org/entity/Q2544859'), ('awlbl', 'Independent Spirit Award for Best Male Lead')]
# [('aw', 'http://www.wikidata.org/entity/Q2295041'), ('awlbl', 'Independent Spirit Award for Best Director')]
# [('aw', 'http://www.wikidata.org/entity/Q1868950'), ('awlbl', 'London Film Critics Circle Award for Actor of the Year')]
# [('aw', 'http://www.wikidata.org/entity/Q952914'), ('awlbl', 'Los Angeles Film Critics Association Award for Best Film')]
# [('aw', 'http://www.wikidata.org/entity/Q503034'), ('awlbl', 'Los Angeles Film Critics Association Award for Best Actor')]
# [('aw', 'http://www.wikidata.org/entity/Q505449'), ('awlbl', 'Los Angeles Film Critics Association Award for Best Director')]
# [('aw', 'http://www.wikidata.org/entity/Q4220897'), ('awlbl', 'MTV Movie Award for Best Dance Sequence')]
# [('aw', 'http://www.wikidata.org/entity/Q540977'), ('awlbl', 'MTV Movie Award for Best Movie')]
# [('aw', 'http://www.wikidata.org/entity/Q1062026'), ('awlbl', 'MTV Movie Award for Best Villain')]
# [('aw', 'http://www.wikidata.org/entity/Q696998'), ('awlbl', 'National Board of Review Award for Best Director')]
# [('aw', 'http://www.wikidata.org/entity/Q1966965'), ('awlbl', 'National Board of Review: Top Ten Films')]
# [('aw', 'http://www.wikidata.org/entity/Q1789102'), ('awlbl', 'National Board of Review Award for Best Film')]
# [('aw', 'http://www.wikidata.org/entity/Q823422'), ('awlbl', 'National Film Registry')]
# [('aw', 'http://www.wikidata.org/entity/Q1315008'), ('awlbl', 'National Society of Film Critics Award for Best Director')]
# [('aw', 'http://www.wikidata.org/entity/Q1720784'), ('awlbl', 'National Society of Film Critics Award for Best Film')]
# [('aw', 'http://www.wikidata.org/entity/Q6978541'), ('awlbl', 'National Society of Film Critics Award for Best Screenplay')]
# [('aw', 'http://www.wikidata.org/entity/Q696972'), ('awlbl', 'New York Film Critics Circle Award for Best Director')]
# [('aw', 'http://www.wikidata.org/entity/Q179808'), ('awlbl', "Palme d'Or")]
# 27

# %% [markdown]
# ## Task 7.1

# %%
# get node of which "Academy Award for Best Production Design" is instance 

queryString = """
SELECT DISTINCT ?o ?olbl
WHERE { 

wd:Q277751 wdt:P31 ?o .
    
# ?o <http://schema.org/name> ?olbl .

} 
ORDER BY ?olbl
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('o', 'http://www.wikidata.org/entity/Q19020'), ('olbl', 'Academy Awards')]
# [('o', 'http://www.wikidata.org/entity/Q96474698'), ('olbl', 'award for best production design')]
# 2

# %%
# GOAL (7.1)
# get all the type of Academy's awards

queryString = """
SELECT DISTINCT ?aw ?awlbl
WHERE { 

# ?aw wdt:P31 wd:Q19020 .
    
# ?aw <http://schema.org/name> ?awlbl .

} 
ORDER BY ?awlbl
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('aw', 'http://www.wikidata.org/entity/Q112243'), ('awlbl', 'Academy Award for Best Original Song')]
# [('aw', 'http://www.wikidata.org/entity/Q3886464'), ('awlbl', 'Academy Award for Best Live Action Short Film, Comedy')]
# [('aw', 'http://www.wikidata.org/entity/Q22117120'), ('awlbl', 'Academy Award for Best Writing')]
# [('aw', 'http://www.wikidata.org/entity/Q103916'), ('awlbl', 'Academy Award for Best Actor')]
# [('aw', 'http://www.wikidata.org/entity/Q102427'), ('awlbl', 'Academy Award for Best Picture')]
# [('aw', 'http://www.wikidata.org/entity/Q107258'), ('awlbl', 'Academy Award for Best Writing, Adapted Screenplay')]
# [('aw', 'http://www.wikidata.org/entity/Q498690'), ('awlbl', 'Academy Award for Best Dance Direction')]
# [('aw', 'http://www.wikidata.org/entity/Q1425151'), ('awlbl', 'Academy Award for Best Documentary (Short Subject)')]
# [('aw', 'http://www.wikidata.org/entity/Q1401974'), ('awlbl', 'Academy Award for Best Short Subject, Two-reel')]
# [('aw', 'http://www.wikidata.org/entity/Q22253131'), ('awlbl', 'Academy Award for Best Art Direction, Color')]
# [('aw', 'http://www.wikidata.org/entity/Q103618'), ('awlbl', 'Academy Award for Best Actress')]
# [('aw', 'http://www.wikidata.org/entity/Q103360'), ('awlbl', 'Academy Award for Best Director')]
# [('aw', 'http://www.wikidata.org/entity/Q830079'), ('awlbl', 'Academy Award for Best Sound')]
# [('aw', 'http://www.wikidata.org/entity/Q3451157'), ('awlbl', 'Academy Award for Best Director (Comedy picture)')]
# [('aw', 'http://www.wikidata.org/entity/Q3886486'), ('awlbl', 'Academy Award for Best Title Writing')]
# [('aw', 'http://www.wikidata.org/entity/Q22752811'), ('awlbl', 'Academy Award for Best Score, Adaptation or Treatment')]
# [('aw', 'http://www.wikidata.org/entity/Q111332'), ('awlbl', 'Academy Award for Best Documentary Feature')]
# [('aw', 'http://www.wikidata.org/entity/Q281939'), ('awlbl', 'Academy Award for Best Film Editing')]
# [('aw', 'http://www.wikidata.org/entity/Q487136'), ('awlbl', 'Academy Award for Best Makeup and Hairstyling')]
# [('aw', 'http://www.wikidata.org/entity/Q488645'), ('awlbl', 'Academy Award for Best Sound Editing')]
# [('aw', 'http://www.wikidata.org/entity/Q917808'), ('awlbl', 'Academy Award for Best Animated Short Film')]
# [('aw', 'http://www.wikidata.org/entity/Q3886463'), ('awlbl', 'Academy Award for Best Engineering Effects')]
# [('aw', 'http://www.wikidata.org/entity/Q22120066'), ('awlbl', 'Academy Award for Best Costume Design, Color')]
# [('aw', 'http://www.wikidata.org/entity/Q22752734'), ('awlbl', 'Academy Award for Best Original Score, no Musical')]
# [('aw', 'http://www.wikidata.org/entity/Q22752868'), ('awlbl', 'Academy Award for Best Original Dramatic or Comedy Score')]
# [('aw', 'http://www.wikidata.org/entity/Q22917729'), ('awlbl', 'Academy Award for Best Special Effects')]
# [('aw', 'http://www.wikidata.org/entity/Q105304'), ('awlbl', 'Academy Award for Best Foreign Language Film')]
# [('aw', 'http://www.wikidata.org/entity/Q106301'), ('awlbl', 'Academy Award for Best Supporting Actress')]
# [('aw', 'http://www.wikidata.org/entity/Q131520'), ('awlbl', 'Academy Award for Best Cinematography')]
# [('aw', 'http://www.wikidata.org/entity/Q1324407'), ('awlbl', 'Academy Award for Best Live Action Short Film')]
# [('aw', 'http://www.wikidata.org/entity/Q21995136'), ('awlbl', 'Academy Award for Best Cinematography, Color')]
# [('aw', 'http://www.wikidata.org/entity/Q21995338'), ('awlbl', 'Academy Award for Best Director, Dramatic Picture')]
# [('aw', 'http://www.wikidata.org/entity/Q21995139'), ('awlbl', 'Academy Award for Best Cinematography, Black-and-White')]
# [('aw', 'http://www.wikidata.org/entity/Q22235329'), ('awlbl', 'Academy Award for Best Original Dramatic Score')]
# [('aw', 'http://www.wikidata.org/entity/Q22253133'), ('awlbl', 'Academy Award for Best Art Direction, Black and White')]
# [('aw', 'http://www.wikidata.org/entity/Q277751'), ('awlbl', 'Academy Award for Best Production Design')]
# [('aw', 'http://www.wikidata.org/entity/Q488651'), ('awlbl', 'Academy Award for Best Original Score')]
# [('aw', 'http://www.wikidata.org/entity/Q41417'), ('awlbl', 'Academy Award for Best Writing, Original Screenplay')]
# [('aw', 'http://www.wikidata.org/entity/Q277536'), ('awlbl', 'Academy Award for Best Costume Design')]
# [('aw', 'http://www.wikidata.org/entity/Q501004'), ('awlbl', 'Academy Award for Best Assistant Director')]
# [('aw', 'http://www.wikidata.org/entity/Q504298'), ('awlbl', 'Academy Award for Best Story')]
# [('aw', 'http://www.wikidata.org/entity/Q2297175'), ('awlbl', 'Academy Award for Best Short Subject, Novelty')]
# [('aw', 'http://www.wikidata.org/entity/Q3886465'), ('awlbl', 'Academy Award for Best Live Action Short Film, Color')]
# [('aw', 'http://www.wikidata.org/entity/Q4671338'), ('awlbl', 'Academy Award for Best Original Musical Score')]
# [('aw', 'http://www.wikidata.org/entity/Q22120095'), ('awlbl', 'Academy Award for Best Costume Design, Black-and-White')]
# [('aw', 'http://www.wikidata.org/entity/Q22335251'), ('awlbl', 'Academy Award for Best Live Action Short Film, One-Reel')]
# [('aw', 'http://www.wikidata.org/entity/Q106800'), ('awlbl', 'Academy Award for Best Animated Feature')]
# [('aw', 'http://www.wikidata.org/entity/Q106291'), ('awlbl', 'Academy Award for Best Supporting Actor')]
# [('aw', 'http://www.wikidata.org/entity/Q393686'), ('awlbl', 'Academy Award for Best Visual Effects')]
# [('aw', 'http://www.wikidata.org/entity/Q22235305'), ('awlbl', 'Academy Award for Best Original Musical or Comedy Score')]
# [('aw', 'http://www.wikidata.org/entity/Q22344608'), ('awlbl', 'Academy Award for Best Original Song Score')]
# [('aw', 'http://www.wikidata.org/entity/Q31193514'), ('awlbl', 'Academy Award for Best Unique and Artistic Picture')]
# [('aw', 'http://www.wikidata.org/entity/Q8636'), ('awlbl', 'Academy Award for Technical Achievement')]
# [('aw', 'http://www.wikidata.org/entity/Q3298549'), ('awlbl', 'Academy Award for Unique and Artistic Production')]
# [('aw', 'http://www.wikidata.org/entity/Q8624'), ('awlbl', 'Academy Award of Merit')]
# [('aw', 'http://www.wikidata.org/entity/Q98924004'), ('awlbl', 'Academy Award to the Producer of the Best Film')]
# [('aw', 'http://www.wikidata.org/entity/Q727328'), ('awlbl', 'Academy Honorary Award')]
# [('aw', 'http://www.wikidata.org/entity/Q489705'), ('awlbl', 'Academy Juvenile Award')]
# [('aw', 'http://www.wikidata.org/entity/Q8610'), ('awlbl', 'Academy Scientific and Technical Award')]
# [('aw', 'http://www.wikidata.org/entity/Q488151'), ('awlbl', 'Gordon E. Sawyer Award')]
# [('aw', 'http://www.wikidata.org/entity/Q844273'), ('awlbl', 'Irving G. Thalberg Memorial Award')]
# [('aw', 'http://www.wikidata.org/entity/Q8250869'), ('awlbl', 'Scientific and Engineering Award')]
# [('aw', 'http://www.wikidata.org/entity/Q2032630'), ('awlbl', 'Special Achievement Academy Award')]
# 63

# %% [markdown]
# ## Task 7.2

# %%
# GOAL (7.2) PART 1
# get predicates from "Academy Awards"

queryString = """
SELECT DISTINCT ?p ?plbl
WHERE { 

wd:Q19020 ?p ?o .
    
# ?p <http://schema.org/name> ?plbl .

} 
ORDER BY ?plbl
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P9084'), ('plbl', 'ABC News topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P9629'), ('plbl', 'Armeniapedia ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8295'), ('plbl', 'AustLit ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6200'), ('plbl', 'BBC News topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2581'), ('plbl', 'BabelNet ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P268'), ('plbl', 'Bibliothèque nationale de France ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5019'), ('plbl', 'Brockhaus Enzyklopädie online ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5905'), ('plbl', 'Comic Vine ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P373'), ('plbl', 'Commons category')]
# [('p', 'http://www.wikidata.org/prop/direct/P935'), ('plbl', 'Commons gallery')]
# [('p', 'http://www.wikidata.org/prop/direct/P3569'), ('plbl', 'Cultureel Woordenboek ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3509'), ('plbl', 'Dagens Nyheter topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6181'), ('plbl', 'Disney A to Z ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1417'), ('plbl', 'Encyclopædia Britannica Online ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2163'), ('plbl', 'FAST ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2013'), ('plbl', 'Facebook ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P4073'), ('plbl', 'Fandom wiki ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P646'), ('plbl', 'Freebase ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P227'), ('plbl', 'GND ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P4013'), ('plbl', 'Giphy username')]
# [('p', 'http://www.wikidata.org/prop/direct/P9100'), ('plbl', 'GitHub topic')]
# [('p', 'http://www.wikidata.org/prop/direct/P7502'), ('plbl', 'Golden ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5337'), ('plbl', 'Google News topics ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1296'), ('plbl', 'Gran Enciclopèdia Catalana ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2924'), ('plbl', 'Great Russian Encyclopedia Online ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7982'), ('plbl', 'Hrvatska enciklopedija ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P345'), ('plbl', 'IMDb ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P269'), ('plbl', 'IdRef ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2003'), ('plbl', 'Instagram username')]
# [('p', 'http://www.wikidata.org/prop/direct/P8408'), ('plbl', 'KBpedia ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6058'), ('plbl', 'Larousse ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P244'), ('plbl', 'Library of Congress authority ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1407'), ('plbl', 'MusicBrainz series ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3222'), ('plbl', 'NE.se ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P691'), ('plbl', 'NKCR AUT ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P349'), ('plbl', 'National Diet Library ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3221'), ('plbl', 'New York Times topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3479'), ('plbl', 'Omni topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3847'), ('plbl', 'Open Library subject ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8349'), ('plbl', 'Proleksis enciklopedija ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3417'), ('plbl', 'Quora topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6081'), ('plbl', 'RIA Novosti reference')]
# [('p', 'http://www.wikidata.org/prop/direct/P7775'), ('plbl', 'RationalWiki ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P4342'), ('plbl', 'Store norske leksikon ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2002'), ('plbl', 'Twitter username')]
# [('p', 'http://www.wikidata.org/prop/direct/P1225'), ('plbl', 'U.S. National Archives Identifier')]
# [('p', 'http://www.wikidata.org/prop/direct/P8814'), ('plbl', 'WordNet 3.1 Synset ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2397'), ('plbl', 'YouTube channel ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2517'), ('plbl', 'category for recipients of this award')]
# [('p', 'http://www.wikidata.org/prop/direct/P1027'), ('plbl', 'conferred by')]
# [('p', 'http://www.wikidata.org/prop/direct/P17'), ('plbl', 'country')]
# [('p', 'http://www.wikidata.org/prop/direct/P1343'), ('plbl', 'described by source')]
# [('p', 'http://www.wikidata.org/prop/direct/P1889'), ('plbl', 'different from')]
# [('p', 'http://www.wikidata.org/prop/direct/P2888'), ('plbl', 'exact match')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('plbl', 'has part')]
# [('p', 'http://www.wikidata.org/prop/direct/P18'), ('plbl', 'image')]
# [('p', 'http://www.wikidata.org/prop/direct/P571'), ('plbl', 'inception')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('plbl', 'instance of')]
# [('p', 'http://www.wikidata.org/prop/direct/P1705'), ('plbl', 'native label')]
# [('p', 'http://www.wikidata.org/prop/direct/P856'), ('plbl', 'official website')]
# [('p', 'http://www.wikidata.org/prop/direct/P8687'), ('plbl', 'social media followers')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('plbl', 'subclass of')]
# [('p', 'http://www.wikidata.org/prop/direct/P910'), ('plbl', "topic's main category")]
# [('p', 'http://www.wikidata.org/prop/direct/P1424'), ('plbl', "topic's main template")]
# [('p', 'http://www.wikidata.org/prop/direct/P4622'), ('plbl', 'trophy awarded')]
# [('p', 'http://www.wikidata.org/prop/direct/P9318'), ('plbl', 'Ávvir topic ID')]
# 66

# %%
# GOAL (7.2) PART 2
# get predicates from Academy's awards

queryString = """
SELECT DISTINCT ?p ?plbl
WHERE { 

# ?aw wdt:P31 wd:Q19020 ;
    # ?p ?o .
    
# ?p <http://schema.org/name> ?plbl .

} 
ORDER BY ?plbl
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P2581'), ('plbl', 'BabelNet ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P373'), ('plbl', 'Commons category')]
# [('p', 'http://www.wikidata.org/prop/direct/P935'), ('plbl', 'Commons gallery')]
# [('p', 'http://www.wikidata.org/prop/direct/P1417'), ('plbl', 'Encyclopædia Britannica Online ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6262'), ('plbl', 'Fandom article ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P646'), ('plbl', 'Freebase ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7502'), ('plbl', 'Golden ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2671'), ('plbl', 'Google Knowledge Graph ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8408'), ('plbl', 'KBpedia ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3553'), ('plbl', 'Zhihu topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P166'), ('plbl', 'award received')]
# [('p', 'http://www.wikidata.org/prop/direct/P2517'), ('plbl', 'category for recipients of this award')]
# [('p', 'http://www.wikidata.org/prop/direct/P1027'), ('plbl', 'conferred by')]
# [('p', 'http://www.wikidata.org/prop/direct/P17'), ('plbl', 'country')]
# [('p', 'http://www.wikidata.org/prop/direct/P576'), ('plbl', 'dissolved, abolished or demolished date')]
# [('p', 'http://www.wikidata.org/prop/direct/P8115'), ('plbl', 'eligible recipient')]
# [('p', 'http://www.wikidata.org/prop/direct/P582'), ('plbl', 'end time')]
# [('p', 'http://www.wikidata.org/prop/direct/P2257'), ('plbl', 'event interval')]
# [('p', 'http://www.wikidata.org/prop/direct/P101'), ('plbl', 'field of work')]
# [('p', 'http://www.wikidata.org/prop/direct/P571'), ('plbl', 'inception')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('plbl', 'instance of')]
# [('p', 'http://www.wikidata.org/prop/direct/P154'), ('plbl', 'logo image')]
# [('p', 'http://www.wikidata.org/prop/direct/P138'), ('plbl', 'named after')]
# [('p', 'http://www.wikidata.org/prop/direct/P1705'), ('plbl', 'native label')]
# [('p', 'http://www.wikidata.org/prop/direct/P856'), ('plbl', 'official website')]
# [('p', 'http://www.wikidata.org/prop/direct/P5008'), ('plbl', 'on focus list of Wikimedia project')]
# [('p', 'http://www.wikidata.org/prop/direct/P361'), ('plbl', 'part of')]
# [('p', 'http://www.wikidata.org/prop/direct/P7084'), ('plbl', 'related category')]
# [('p', 'http://www.wikidata.org/prop/direct/P580'), ('plbl', 'start time')]
# [('p', 'http://www.wikidata.org/prop/direct/P910'), ('plbl', "topic's main category")]
# [('p', 'http://www.wikidata.org/prop/direct/P1424'), ('plbl', "topic's main template")]
# [('p', 'http://www.wikidata.org/prop/direct/P1346'), ('plbl', 'winner')]
# 32

# %%
# GOAL (7.3) PART 2
# get award for Quentin Tarantino

queryString = """
SELECT DISTINCT ?aw ?awlbl
WHERE { 

wd:Q3772 wdt:P166 ?aw .

# ?aw wdt:P31 wd:Q19020 .
    
# ?aw <http://schema.org/name> ?awlbl .

} 
ORDER BY ?awlbl
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('aw', 'http://www.wikidata.org/entity/Q41417'), ('awlbl', 'Academy Award for Best Writing, Original Screenplay')]
# 1

# %% [markdown]
# ## Task 7

# %%
# get awards and nominations of Quentin Tarantino and his films

queryString = """
SELECT ?dir ?film_awards ?film_nominations ?dir_awards ?dir_nominations
WHERE {

    {
        SELECT ?dir (COUNT(?f_aw) AS ?film_awards)
        WHERE {
            # ?film wdt:P31 wd:Q11424 ;
                wdt:P57 wd:Q3772 .

            # ?film wdt:P166 ?f_aw .

            # ?f_aw wdt:P31 wd:Q19020 .

            wd:Q3772 <http://schema.org/name> ?dir .
        }
        GROUP BY ?dir
    }
    
    {
    
        SELECT ?dir (COUNT(?f_nom) AS ?film_nominations)
        WHERE {
        
            # ?film wdt:P31 wd:Q11424 ;
                wdt:P57 wd:Q3772 .

            # ?film wdt:P1411 ?f_nom .

            # ?f_nom wdt:P31 wd:Q19020 .
            
            wd:Q3772 <http://schema.org/name> ?dir .
        }
        GROUP BY ?dir
    
    }
    
    {
        SELECT ?dir (COUNT(?d_aw) AS ?dir_awards)
        WHERE {
        
            wd:Q3772 wdt:P166 ?d_aw .

            # ?d_aw wdt:P31 wd:Q19020 .
            
            wd:Q3772 <http://schema.org/name> ?dir .
        }
        GROUP BY ?dir

    }

    {
        SELECT ?dir (COUNT(?d_nom) AS ?dir_nominations)
        WHERE {
        
            wd:Q3772 wdt:P1411 ?d_nom .

            # ?d_nom wdt:P31 wd:Q19020 .
            
            wd:Q3772 <http://schema.org/name> ?dir .
        
        }
        GROUP BY ?dir
    }
}
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('dir', 'Quentin Tarantino'), ('film_awards', '7'), ('film_nominations', '24'), ('dir_awards', '1'), ('dir_nominations', '2')]
# 1

# %%
# GOAL (7)
# get awards and nominations about both directors and their films

queryString = """
SELECT ?dir ?dir_awards ?dir_nominations ?film_awards ?film_nominations
WHERE 
{
    {
        {
            SELECT ?dir (COUNT(?f_aw) AS ?film_awards)
            WHERE {
                # ?film wdt:P31 wd:Q11424 ;
                    wdt:P57 wd:Q3772 .

                # ?film wdt:P166 ?f_aw .

                # ?f_aw wdt:P31 wd:Q19020 .

                wd:Q3772 <http://schema.org/name> ?dir .
            }
            GROUP BY ?dir
        }

        {

            SELECT ?dir (COUNT(?f_nom) AS ?film_nominations)
            WHERE {

                # ?film wdt:P31 wd:Q11424 ;
                    wdt:P57 wd:Q3772 .

                # ?film wdt:P1411 ?f_nom .

                # ?f_nom wdt:P31 wd:Q19020 .

                wd:Q3772 <http://schema.org/name> ?dir .
            }
            GROUP BY ?dir

        }

        {
            SELECT ?dir (COUNT(?d_aw) AS ?dir_awards)
            WHERE {

                wd:Q3772 wdt:P166 ?d_aw .

                # ?d_aw wdt:P31 wd:Q19020 .

                wd:Q3772 <http://schema.org/name> ?dir .
            }
            GROUP BY ?dir

        }

        {
            SELECT ?dir (COUNT(?d_nom) AS ?dir_nominations)
            WHERE {

                wd:Q3772 wdt:P1411 ?d_nom .

                # ?d_nom wdt:P31 wd:Q19020 .

                wd:Q3772 <http://schema.org/name> ?dir .

            }
            GROUP BY ?dir
        }
    }

UNION

    {
        {
            SELECT ?dir (COUNT(?f_aw) AS ?film_awards)
            WHERE {
                # ?film wdt:P31 wd:Q11424 ;
                    wdt:P57 wd:Q25089 .

                # ?film wdt:P166 ?f_aw .

                # ?f_aw wdt:P31 wd:Q19020 .

                wd:Q25089 <http://schema.org/name> ?dir .
            }
            GROUP BY ?dir
        }

        {

            SELECT ?dir (COUNT(?f_nom) AS ?film_nominations)
            WHERE {

                # ?film wdt:P31 wd:Q11424 ;
                    wdt:P57 wd:Q25089 .

                # ?film wdt:P1411 ?f_nom .

                # ?f_nom wdt:P31 wd:Q19020 .

                wd:Q25089 <http://schema.org/name> ?dir .
            }
            GROUP BY ?dir

        }

        {
            SELECT ?dir (COUNT(?d_aw) AS ?dir_awards)
            WHERE {

                wd:Q25089 wdt:P166 ?d_aw .

                # ?d_aw wdt:P31 wd:Q19020 .

                wd:Q25089 <http://schema.org/name> ?dir .
            }
            GROUP BY ?dir

        }

        {
            SELECT ?dir (COUNT(?d_nom) AS ?dir_nominations)
            WHERE {

                wd:Q25089 wdt:P1411 ?d_nom .

                # ?d_nom wdt:P31 wd:Q19020 .

                wd:Q25089 <http://schema.org/name> ?dir .

            }
            GROUP BY ?dir
        }
    }
}
ORDER BY ?dir

"""

print("Results")
run_query(queryString)

# %% [markdown]
# ## Task 7.4

# %%
# GOAL (7.4)
# get awards and nominations about both directors and their films
#
# Note: this is a second version of the previous query

queryString = """
SELECT ?dirlbl (COUNT(?d_aw) AS ?dir_awards) (COUNT(?d_nom) AS ?dir_nominations) (COUNT(?f_aw) AS ?film_awards) (COUNT(?f_nom) AS ?film_nominations)
WHERE 
{
    {
        # ?dir wdt:P106 wd:Q2526255 ;
            wdt:P166 ?d_aw .

        # ?d_aw wdt:P31 wd:Q19020 .

        # ?dir <http://schema.org/name> ?dirlbl .

        FILTER (?dir = wd:Q25089 || ?dir = wd:Q3772)
    }
    UNION
    {
        # ?dir wdt:P106 wd:Q2526255 ;
            wdt:P1411 ?d_nom .

        # ?d_nom wdt:P31 wd:Q19020 .

        # ?dir <http://schema.org/name> ?dirlbl .

        FILTER (?dir = wd:Q25089 || ?dir = wd:Q3772)
    }
    UNION
    {
        # ?dir wdt:P106 wd:Q2526255 .

        # ?film wdt:P31 wd:Q11424 ;
            wdt:P57 ?dir .

        # ?film wdt:P166 ?f_aw .

        # ?f_aw wdt:P31 wd:Q19020 .

        # ?dir <http://schema.org/name> ?dirlbl .

        FILTER (?dir = wd:Q25089 || ?dir = wd:Q3772)
    }
    UNION
    {
        # ?dir wdt:P106 wd:Q2526255 .

        # ?film wdt:P31 wd:Q11424 ;
            wdt:P57 ?dir .

        # ?film wdt:P1411 ?f_nom .

        # ?f_nom wdt:P31 wd:Q19020 .

        # ?dir <http://schema.org/name> ?dirlbl .

        FILTER (?dir = wd:Q25089 || ?dir = wd:Q3772)
    }
        
}
ORDER BY ?dirlbl

"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('dirlbl', 'Quentin Tarantino'), ('dir_awards', '1'), ('dir_nominations', '2'), ('film_awards', '7'), ('film_nominations', '24')]
# [('dirlbl', 'Woody Allen'), ('dir_awards', '2'), ('dir_nominations', '3'), ('film_awards', '12'), ('film_nominations', '52')]
# 2

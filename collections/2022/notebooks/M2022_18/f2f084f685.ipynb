# %% [markdown]
# # General instructions
#
# The goal of the project is to materialize a set of **exploratory workloads** over a real-world, large-scale,  open-domain KG: [WikiData](https://www.wikidata.org/wiki/Wikidata:Main_Page)
#
# An exploratory workload  is composed by a set of queries, where each query is related to the information obtained previously.
#
# An exploratory workload starts with a usually vague, open ended question, and does not assume the person issuing the workload has a clear understanding of the data contained in the target database or its structure.
#
# Remeber that:
#
# 1. All the queries must run in the python notebook
# 2. You can use classes and properties only if you find them via a SPARQL query that must be present in the notebook
# 3. You do not delete useless queries. Keep everything that is synthatically valid
#
# ```
# ?p <http://schema.org/name> ?name .
# ```
#
#     is the BGP returning a human-readable name of a property or a class in Wikidata.

# %%
## SETUP used later

from SPARQLWrapper import SPARQLWrapper, JSON


prefixString = """
##-f2f084f685-##
PREFIX wd: <http://www.wikidata.org/entity/> 
PREFIX wdt: <http://www.wikidata.org/prop/direct/> 
PREFIX sc: <http://schema.org/>
"""

# select and construct queries
def run_query(queryString,verbose = True):
    to_run = prefixString + "\n" + queryString

    sparql = SPARQLWrapper("http://a256-gc1-03.srv.aau.dk:5820/sparql")
    sparql.setTimeout(300)
    sparql.setReturnFormat(JSON)
    sparql.setQuery(to_run)

    try :
        results = sparql.query()
        json_results = results.convert()
        if len(json_results['results']['bindings'])==0:
            print("Empty")
            return []
        array = []
        for bindings in json_results['results']['bindings']:
            app =  [ (var, value['value'])  for var, value in bindings.items() ] 
            if verbose:
                print( app)
            array.append(app)
        if verbose:
            print(len(array))
        return array

    except Exception as e :
        print("The operation failed", e)
    
# ASk queries
def run_ask_query(queryString):
    to_run = prefixString + "\n" + queryString

    sparql = SPARQLWrapper("http://a256-gc1-03.srv.aau.dk:5820/sparql")
    sparql.setTimeout(300)
    sparql.setReturnFormat(JSON)
    sparql.setQuery(to_run)

    try :
        return sparql.query().convert()

    except Exception as e :
        print("The operation failed", e)

# %% [markdown]
# # Movie Workflow Series ("Film Genre and directors explorative search")
#
# Consider the following exploratory information need:
#
# > investigate the results concerning the different film genre over years and the directors for the cinema.

# %% [markdown]
# ## Useful URIs for the current workflow
# The following are given:
#
# | IRI           | Description   | Role      |
# | -----------   | -----------   |-----------|
# | `wdt:P1647`   | subproperty   | predicate |
# | `wdt:P31`     | instance of   | predicate |
# | `wdt:P106`    | occupation    | predicate |
# | `wdt:P279`    | subclass      | predicate |
# | `wdt:P27`     | nationality   | predicate |
# | `wdt:P3342`     | Significant person       | predicate |
# | `wd:Q5`| Human       | node |
# | `wd:Q25089`| Woody Allen       | node |
# | `wd:Q3772`| Quentin Tarantino      | node |

# %% [markdown]
# Also consider
#
# ```
# wd:Q25089 ?p ?obj .
# ```
#
# is the BGP to retrieve all **properties of Woody Allen**
#
# Please consider that when you return a resource, you should return the IRI and the label of the resource. In particular, when the task require you to identify a BGP the result set must always be a list of couples IRI - label.
#
# The workload should:
#
#
# 1. Identify the BGP for films
#
# 2. Identify the BGP for director
#
# 3. Identify the BGP for film genre
#
# 4. Find how many western films are been released in each european country from 2010-01-01 to 2015-31-12 (the result set must be country IRI, label and #films).
#
# 5. Consider only films directed by Woody Allen or Quentin Tarantino. Then consider the date of publication of these films (take the first one if there are more than one date of publication). Return the year with more films release for the two director (the result set must be two elements and for each element there must be present the director IRI, the label of the IRI, the year and the number of films).
#
# 6. Identify the BGP for Academy Awards
#
# 7. Consider films directed by Woody Allen or Quentin Tarantino separately. Return the film which won more Academy Awards for the two directors (the result set must be two elements - one related to Allen and the other related to Tarantino -  and for each element there must be present the director IRI with its label, the film IRI with its label and the number of Academy awards won).
#
# 8. Consider the set of films directed by Allen or Tarantino. Return for each Academy Award the total number of nomination of these films (the result set must be a list of triples Academy Award IRI, label and #nomination).

# %% [markdown]
# ## Task 1
# Identify the BGP for films

# %%
# query example
queryString = """
SELECT DISTINCT ?p ?name
WHERE {
   # bind something
   wd:Q25089 ?p ?obj .
   # get the label
   # ?p sc:name ?name.
}
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P1003'), ('name', 'National Library of Romania ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1005'), ('name', 'Portuguese National Library ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1006'), ('name', 'Nationale Thesaurus voor Auteurs ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1015'), ('name', 'NORAF ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P103'), ('name', 'native language')]
# [('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('p', 'http://www.wikidata.org/prop/direct/P108'), ('name', 'employer')]
# [('p', 'http://www.wikidata.org/prop/direct/P109'), ('name', 'signature')]
# [('p', 'http://www.wikidata.org/prop/direct/P1150'), ('name', 'Regensburg Classification')]
# [('p', 'http://www.wikidata.org/prop/direct/P1207'), ('name', 'NUKAT ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1220'), ('name', 'Internet Broadway Database person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1233'), ('name', 'Internet Speculative Fiction Database author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1263'), ('name', 'NNDB people ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1266'), ('name', 'AlloCiné person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1273'), ('name', 'CANTIC ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1280'), ('name', 'CONOR.SI ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1283'), ('name', 'filmography')]
# [('p', 'http://www.wikidata.org/prop/direct/P1284'), ('name', 'Munzinger person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1296'), ('name', 'Gran Enciclopèdia Catalana ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1303'), ('name', 'instrument')]
# 20

# %%
# query example
# let's find objects of node Quentin Tarantino
queryString = """
SELECT DISTINCT ?obj ?name
WHERE {
   # bind something
   wd:Q3772 ?p ?obj .
   # get the label
   # ?obj sc:name ?name.
}
LIMIT 50
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('obj', 'http://www.wikidata.org/entity/Q212026'), ('name', 'Mira Sorvino')]
# [('obj', 'http://www.wikidata.org/entity/Q2566554'), ('name', '48th British Academy Film Awards')]
# [('obj', 'http://www.wikidata.org/entity/Q833154'), ('name', 'Edgar Awards')]
# [('obj', 'http://www.wikidata.org/entity/Q103360'), ('name', 'Academy Award for Best Director')]
# [('obj', 'http://www.wikidata.org/entity/Q10798782'), ('name', 'television actor')]
# [('obj', 'http://www.wikidata.org/entity/Q10800557'), ('name', 'film actor')]
# [('obj', 'http://www.wikidata.org/entity/Q113068'), ('name', 'Hungarian Order of Merit')]
# [('obj', 'http://www.wikidata.org/entity/Q13452531'), ('name', 'Commandeur des Arts et des Lettres\u200e')]
# [('obj', 'http://www.wikidata.org/entity/Q17290934'), ('name', 'Lentapedia')]
# [('obj', 'http://www.wikidata.org/entity/Q179808'), ('name', "Palme d'Or")]
# [('obj', 'http://www.wikidata.org/entity/Q17985761'), ('name', 'star on Hollywood Walk of Fame')]
# [('obj', 'http://www.wikidata.org/entity/Q1860'), ('name', 'English')]
# [('obj', 'http://www.wikidata.org/entity/Q188'), ('name', 'German')]
# [('obj', 'http://www.wikidata.org/entity/Q188473'), ('name', 'action film')]
# [('obj', 'http://www.wikidata.org/entity/Q188740'), ('name', 'Museum of Modern Art')]
# [('obj', 'http://www.wikidata.org/entity/Q2526255'), ('name', 'film director')]
# [('obj', 'http://www.wikidata.org/entity/Q28389'), ('name', 'screenwriter')]
# [('obj', 'http://www.wikidata.org/entity/Q30'), ('name', 'United States of America')]
# [('obj', 'http://www.wikidata.org/entity/Q3282637'), ('name', 'film producer')]
# [('obj', 'http://www.wikidata.org/entity/Q33999'), ('name', 'actor')]
# [('obj', 'http://www.wikidata.org/entity/Q3455803'), ('name', 'director')]
# [('obj', 'http://www.wikidata.org/entity/Q36180'), ('name', 'writer')]
# [('obj', 'http://www.wikidata.org/entity/Q41417'), ('name', 'Academy Award for Best Writing, Original Screenplay')]
# [('obj', 'http://www.wikidata.org/entity/Q463303'), ('name', 'American Academy of Arts and Sciences')]
# [('obj', 'http://www.wikidata.org/entity/Q490861'), ('name', '70th Golden Globe Awards')]
# [('obj', 'http://www.wikidata.org/entity/Q5'), ('name', 'human')]
# [('obj', 'http://www.wikidata.org/entity/Q5043'), ('name', 'Christianity')]
# [('obj', 'http://www.wikidata.org/entity/Q52382875'), ('name', 'AAAS Fellow')]
# [('obj', 'http://www.wikidata.org/entity/Q6581097'), ('name', 'male')]
# [('obj', 'http://www.wikidata.org/entity/Q67311526'), ('name', 'Obalky knih.cz')]
# [('obj', 'http://www.wikidata.org/entity/Q7042855'), ('name', 'film editor')]
# [('obj', 'http://www.wikidata.org/entity/Q73555012'), ('name', 'works protected by copyrights')]
# [('obj', 'http://www.wikidata.org/entity/Q1377772'), ('name', 'European Film Award for Best Non-European Film')]
# [('obj', 'http://www.wikidata.org/entity/Q1789102'), ('name', 'National Board of Review Award for Best Film')]
# [('obj', 'http://www.wikidata.org/entity/Q23958341'), ('name', 'President of the Jury at the Cannes Festival')]
# [('obj', 'http://www.wikidata.org/entity/Q974693'), ('name', 'Italian American')]
# [('obj', 'http://www.wikidata.org/entity/Q1075293'), ('name', 'Irish Americans')]
# [('obj', 'http://www.wikidata.org/entity/Q185582'), ('name', 'Knoxville')]
# [('obj', 'http://www.wikidata.org/entity/Q51581'), ('name', 'Howard Hawks')]
# [('obj', 'http://www.wikidata.org/entity/Q41375'), ('name', 'BAFTA Award for Best Original Screenplay')]
# [('obj', 'http://www.wikidata.org/entity/Q849124'), ('name', 'Golden Globe Award for Best Screenplay')]
# [('obj', 'http://www.wikidata.org/entity/Q93439'), ('name', '52nd Golden Globe Awards')]
# [('obj', 'http://www.wikidata.org/entity/Q459290'), ('name', 'independent film')]
# [('obj', 'http://www.wikidata.org/entity/Q1158484'), ('name', 'Quentin')]
# [('obj', 'http://www.wikidata.org/entity/Q21487819'), ('name', 'Tarantino')]
# [('obj', 'http://www.wikidata.org/entity/Q3404975'), ('name', 'Lumière Award, Lyon Festival of cinema')]
# [('obj', 'http://www.wikidata.org/entity/Q245949'), ('name', '36th César Awards')]
# [('obj', 'http://www.wikidata.org/entity/Q32947601'), ('name', 'Daniella Pick')]
# [('obj', 'http://www.wikidata.org/entity/Q2690424'), ('name', '66th British Academy Film Awards')]
# [('obj', 'http://www.wikidata.org/entity/Q5274115'), ('name', 'Didem Erol')]
# 50

# %%
# query example
# [('obj', 'http://www.wikidata.org/entity/Q188473'), ('name', 'action film')]
queryString = """
SELECT DISTINCT ?p ?name
WHERE {
   # bind something
   wd:Q188473 ?p ?obj .
   # get the label
   # ?p sc:name ?name.
}
LIMIT 50
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P1813'), ('name', 'short name')]
# [('p', 'http://www.wikidata.org/prop/direct/P227'), ('name', 'GND ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2347'), ('name', 'YSO ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2354'), ('name', 'has list')]
# [('p', 'http://www.wikidata.org/prop/direct/P2581'), ('name', 'BabelNet ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('name', 'subclass of')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('name', 'instance of')]
# [('p', 'http://www.wikidata.org/prop/direct/P3569'), ('name', 'Cultureel Woordenboek ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P373'), ('name', 'Commons category')]
# [('p', 'http://www.wikidata.org/prop/direct/P508'), ('name', 'BNCF Thesaurus ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P646'), ('name', 'Freebase ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8408'), ('name', 'KBpedia ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P910'), ('name', "topic's main category")]
# [('p', 'http://www.wikidata.org/prop/direct/P9084'), ('name', 'ABC News topic ID')]
# 14

# %%
# query example
# [('obj', 'http://www.wikidata.org/entity/Q188473'), ('name', 'action film')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('name', 'subclass of')]
queryString = """
SELECT DISTINCT ?obj ?name
WHERE {
   # bind something
   wd:Q188473 wdt:P279 ?obj .
   # get the label
   # ?obj sc:name ?name.
}
LIMIT 50
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('obj', 'http://www.wikidata.org/entity/Q11424'), ('name', 'film')]
# [('obj', 'http://www.wikidata.org/entity/Q1762165'), ('name', 'action fiction')]
# 2

# %%
# query example
# [('obj', 'http://www.wikidata.org/entity/Q188473'), ('name', 'action film')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('name', 'subclass of')]
# FILTER by "film"
queryString = """
SELECT DISTINCT ?obj ?name
WHERE {
   # bind something
   wd:Q188473 wdt:P279 ?obj .
   # get the label
   # ?obj sc:name ?name.
   FILTER(regex(?name,"film"))
}
LIMIT 50
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('obj', 'http://www.wikidata.org/entity/Q11424'), ('name', 'film')]
# 1

# %%
# query example
# [('obj', 'http://www.wikidata.org/entity/Q188473'), ('name', 'action film')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('name', 'subclass of')]
# [('obj', 'http://www.wikidata.org/entity/Q11424'), ('name', 'film')]
# FILTER by "film"
# reterive BGP for 'film'
queryString = """
SELECT DISTINCT ?p ?name
WHERE {
   # bind something
   wd:Q11424 ?p ?obj .
   # get the label
   # ?p sc:name ?name.
   #FILTER(regex(?name,"film"))
}
LIMIT 50
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P1014'), ('name', 'Art & Architecture Thesaurus ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1036'), ('name', 'Dewey Decimal Classification')]
# [('p', 'http://www.wikidata.org/prop/direct/P1051'), ('name', 'PSH ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1151'), ('name', "topic's main Wikimedia portal")]
# [('p', 'http://www.wikidata.org/prop/direct/P1225'), ('name', 'U.S. National Archives Identifier')]
# [('p', 'http://www.wikidata.org/prop/direct/P1245'), ('name', 'OmegaWiki Defined Meaning')]
# [('p', 'http://www.wikidata.org/prop/direct/P1256'), ('name', 'Iconclass notation')]
# [('p', 'http://www.wikidata.org/prop/direct/P1343'), ('name', 'described by source')]
# [('p', 'http://www.wikidata.org/prop/direct/P1368'), ('name', 'LNB ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1417'), ('name', 'Encyclopædia Britannica Online ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1424'), ('name', "topic's main template")]
# [('p', 'http://www.wikidata.org/prop/direct/P1617'), ('name', 'BBC Things ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1709'), ('name', 'equivalent class')]
# [('p', 'http://www.wikidata.org/prop/direct/P18'), ('name', 'image')]
# [('p', 'http://www.wikidata.org/prop/direct/P1889'), ('name', 'different from')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('name', 'properties for this type')]
# [('p', 'http://www.wikidata.org/prop/direct/P2167'), ('name', 'UNSPSC Code')]
# [('p', 'http://www.wikidata.org/prop/direct/P227'), ('name', 'GND ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2347'), ('name', 'YSO ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P244'), ('name', 'Library of Congress authority ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2579'), ('name', 'studied by')]
# [('p', 'http://www.wikidata.org/prop/direct/P2581'), ('name', 'BabelNet ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2612'), ('name', 'TED topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P268'), ('name', 'Bibliothèque nationale de France ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('name', 'subclass of')]
# [('p', 'http://www.wikidata.org/prop/direct/P2888'), ('name', 'exact match')]
# [('p', 'http://www.wikidata.org/prop/direct/P2959'), ('name', 'permanent duplicated item')]
# [('p', 'http://www.wikidata.org/prop/direct/P3106'), ('name', 'Guardian topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3221'), ('name', 'New York Times topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3417'), ('name', 'Quora topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P349'), ('name', 'National Diet Library ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3553'), ('name', 'Zhihu topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P373'), ('name', 'Commons category')]
# [('p', 'http://www.wikidata.org/prop/direct/P3827'), ('name', 'JSTOR topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3832'), ('name', 'Europeana Fashion Vocabulary ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3911'), ('name', 'STW Thesaurus for Economics ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3916'), ('name', 'UNESCO Thesaurus ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3921'), ('name', 'Wikidata SPARQL query equivalent')]
# [('p', 'http://www.wikidata.org/prop/direct/P3984'), ('name', 'subreddit')]
# [('p', 'http://www.wikidata.org/prop/direct/P4527'), ('name', 'UK Parliament thesaurus ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P460'), ('name', 'said to be the same as')]
# [('p', 'http://www.wikidata.org/prop/direct/P486'), ('name', 'MeSH descriptor ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P4953'), ('name', 'Library of Congress Genre/Form Terms ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5008'), ('name', 'on focus list of Wikimedia project')]
# [('p', 'http://www.wikidata.org/prop/direct/P508'), ('name', 'BNCF Thesaurus ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5125'), ('name', 'Wikimedia outline')]
# [('p', 'http://www.wikidata.org/prop/direct/P5198'), ('name', 'ASC Leiden Thesaurus ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5250'), ('name', 'IAB code')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('name', 'has part')]
# [('p', 'http://www.wikidata.org/prop/direct/P5357'), ('name', 'The Encyclopedia of Science Fiction ID')]
# 50

# %%
# let's try to retrieve all the predicates and objs of film "What's Up, Tiger Lily?"
queryString = """
SELECT DISTINCT ?p ?pName ?obj ?objName
WHERE {
   # bind something
   wd:Q971865 ?p ?obj .
   # get the label
   # ?obj sc:name ?objName.
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P58'), ('obj', 'http://www.wikidata.org/entity/Q25089'), ('objName', 'Woody Allen')]
# [('p', 'http://www.wikidata.org/prop/direct/P161'), ('obj', 'http://www.wikidata.org/entity/Q25089'), ('objName', 'Woody Allen')]
# [('p', 'http://www.wikidata.org/prop/direct/P57'), ('obj', 'http://www.wikidata.org/entity/Q25089'), ('objName', 'Woody Allen')]
# [('p', 'http://www.wikidata.org/prop/direct/P750'), ('obj', 'http://www.wikidata.org/entity/Q465224'), ('objName', 'American International Pictures')]
# [('p', 'http://www.wikidata.org/prop/direct/P162'), ('obj', 'http://www.wikidata.org/entity/Q376138'), ('objName', 'Charles H. Joffe')]
# [('p', 'http://www.wikidata.org/prop/direct/P344'), ('obj', 'http://www.wikidata.org/entity/Q6381680'), ('objName', 'Kazuo Yamada')]
# [('p', 'http://www.wikidata.org/prop/direct/P175'), ('obj', 'http://www.wikidata.org/entity/Q1053608'), ('objName', "The Lovin' Spoonful")]
# [('p', 'http://www.wikidata.org/prop/direct/P86'), ('obj', 'http://www.wikidata.org/entity/Q1053608'), ('objName', "The Lovin' Spoonful")]
# [('p', 'http://www.wikidata.org/prop/direct/P161'), ('obj', 'http://www.wikidata.org/entity/Q1053608'), ('objName', "The Lovin' Spoonful")]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('obj', 'http://www.wikidata.org/entity/Q11424'), ('objName', 'film')]
# [('p', 'http://www.wikidata.org/prop/direct/P840'), ('obj', 'http://www.wikidata.org/entity/Q17'), ('objName', 'Japan')]
# [('p', 'http://www.wikidata.org/prop/direct/P364'), ('obj', 'http://www.wikidata.org/entity/Q1860'), ('objName', 'English')]
# [('p', 'http://www.wikidata.org/prop/direct/P462'), ('obj', 'http://www.wikidata.org/entity/Q22006653'), ('objName', 'color')]
# [('p', 'http://www.wikidata.org/prop/direct/P136'), ('obj', 'http://www.wikidata.org/entity/Q2297927'), ('objName', 'spy film')]
# [('p', 'http://www.wikidata.org/prop/direct/P495'), ('obj', 'http://www.wikidata.org/entity/Q30'), ('objName', 'United States of America')]
# [('p', 'http://www.wikidata.org/prop/direct/P437'), ('obj', 'http://www.wikidata.org/entity/Q723685'), ('objName', 'video on demand')]
# [('p', 'http://www.wikidata.org/prop/direct/P750'), ('obj', 'http://www.wikidata.org/entity/Q907311'), ('objName', 'Netflix')]
# [('p', 'http://www.wikidata.org/prop/direct/P1981'), ('obj', 'http://www.wikidata.org/entity/Q20644797'), ('objName', 'FSK 16')]
# [('p', 'http://www.wikidata.org/prop/direct/P272'), ('obj', 'http://www.wikidata.org/entity/Q875920'), ('objName', 'Toho')]
# [('p', 'http://www.wikidata.org/prop/direct/P161'), ('obj', 'http://www.wikidata.org/entity/Q271861'), ('objName', 'Akiko Wakabayashi')]
# [('p', 'http://www.wikidata.org/prop/direct/P161'), ('obj', 'http://www.wikidata.org/entity/Q967761'), ('objName', 'John Sebastian')]
# [('p', 'http://www.wikidata.org/prop/direct/P58'), ('obj', 'http://www.wikidata.org/entity/Q12270304'), ('objName', 'Mickey Rose')]
# [('p', 'http://www.wikidata.org/prop/direct/P161'), ('obj', 'http://www.wikidata.org/entity/Q12270304'), ('objName', 'Mickey Rose')]
# [('p', 'http://www.wikidata.org/prop/direct/P161'), ('obj', 'http://www.wikidata.org/entity/Q273532'), ('objName', 'Louise Lasser')]
# [('p', 'http://www.wikidata.org/prop/direct/P58'), ('obj', 'http://www.wikidata.org/entity/Q273532'), ('objName', 'Louise Lasser')]
# [('p', 'http://www.wikidata.org/prop/direct/P57'), ('obj', 'http://www.wikidata.org/entity/Q27351'), ('objName', 'Senkichi Taniguchi')]
# [('p', 'http://www.wikidata.org/prop/direct/P161'), ('obj', 'http://www.wikidata.org/entity/Q11356032'), ('objName', 'Tatsuya Mihashi')]
# [('p', 'http://www.wikidata.org/prop/direct/P161'), ('obj', 'http://www.wikidata.org/entity/Q3751773'), ('objName', 'Frank Buxton')]
# [('p', 'http://www.wikidata.org/prop/direct/P161'), ('obj', 'http://www.wikidata.org/entity/Q3674850'), ('objName', 'China Lee')]
# [('p', 'http://www.wikidata.org/prop/direct/P161'), ('obj', 'http://www.wikidata.org/entity/Q449493'), ('objName', 'Mie Hama')]
# [('p', 'http://www.wikidata.org/prop/direct/P58'), ('obj', 'http://www.wikidata.org/entity/Q3189161'), ('objName', 'Julie Bennett')]
# 31

# %% [markdown]
# Final query for this task

# %%
# write your final query
queryString = """
SELECT DISTINCT ?obj ?objName
WHERE {
   # bind something
   wd:Q971865 wdt:P31 ?obj .
   # get the label
   # ?obj sc:name ?objName.
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('obj', 'http://www.wikidata.org/entity/Q11424'), ('objName', 'film')]
# 1

# %% [markdown]
# ## Task 2
# Identify the BGP for director

# %%
# write your queries
# query example
queryString = """
SELECT DISTINCT ?obj ?name
WHERE {
   # bind something
   wd:Q3772 ?p ?obj .
   # get the label
   # ?obj sc:name ?name.
}
LIMIT 50
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('obj', 'http://www.wikidata.org/entity/Q212026'), ('name', 'Mira Sorvino')]
# [('obj', 'http://www.wikidata.org/entity/Q2566554'), ('name', '48th British Academy Film Awards')]
# [('obj', 'http://www.wikidata.org/entity/Q833154'), ('name', 'Edgar Awards')]
# [('obj', 'http://www.wikidata.org/entity/Q103360'), ('name', 'Academy Award for Best Director')]
# [('obj', 'http://www.wikidata.org/entity/Q10798782'), ('name', 'television actor')]
# [('obj', 'http://www.wikidata.org/entity/Q10800557'), ('name', 'film actor')]
# [('obj', 'http://www.wikidata.org/entity/Q113068'), ('name', 'Hungarian Order of Merit')]
# [('obj', 'http://www.wikidata.org/entity/Q13452531'), ('name', 'Commandeur des Arts et des Lettres\u200e')]
# [('obj', 'http://www.wikidata.org/entity/Q17290934'), ('name', 'Lentapedia')]
# [('obj', 'http://www.wikidata.org/entity/Q179808'), ('name', "Palme d'Or")]
# [('obj', 'http://www.wikidata.org/entity/Q17985761'), ('name', 'star on Hollywood Walk of Fame')]
# [('obj', 'http://www.wikidata.org/entity/Q1860'), ('name', 'English')]
# [('obj', 'http://www.wikidata.org/entity/Q188'), ('name', 'German')]
# [('obj', 'http://www.wikidata.org/entity/Q188473'), ('name', 'action film')]
# [('obj', 'http://www.wikidata.org/entity/Q188740'), ('name', 'Museum of Modern Art')]
# [('obj', 'http://www.wikidata.org/entity/Q2526255'), ('name', 'film director')]
# [('obj', 'http://www.wikidata.org/entity/Q28389'), ('name', 'screenwriter')]
# [('obj', 'http://www.wikidata.org/entity/Q30'), ('name', 'United States of America')]
# [('obj', 'http://www.wikidata.org/entity/Q3282637'), ('name', 'film producer')]
# [('obj', 'http://www.wikidata.org/entity/Q33999'), ('name', 'actor')]
# [('obj', 'http://www.wikidata.org/entity/Q3455803'), ('name', 'director')]
# [('obj', 'http://www.wikidata.org/entity/Q36180'), ('name', 'writer')]
# [('obj', 'http://www.wikidata.org/entity/Q41417'), ('name', 'Academy Award for Best Writing, Original Screenplay')]
# [('obj', 'http://www.wikidata.org/entity/Q463303'), ('name', 'American Academy of Arts and Sciences')]
# [('obj', 'http://www.wikidata.org/entity/Q490861'), ('name', '70th Golden Globe Awards')]
# [('obj', 'http://www.wikidata.org/entity/Q5'), ('name', 'human')]
# [('obj', 'http://www.wikidata.org/entity/Q5043'), ('name', 'Christianity')]
# [('obj', 'http://www.wikidata.org/entity/Q52382875'), ('name', 'AAAS Fellow')]
# [('obj', 'http://www.wikidata.org/entity/Q6581097'), ('name', 'male')]
# [('obj', 'http://www.wikidata.org/entity/Q67311526'), ('name', 'Obalky knih.cz')]
# [('obj', 'http://www.wikidata.org/entity/Q7042855'), ('name', 'film editor')]
# [('obj', 'http://www.wikidata.org/entity/Q73555012'), ('name', 'works protected by copyrights')]
# [('obj', 'http://www.wikidata.org/entity/Q1377772'), ('name', 'European Film Award for Best Non-European Film')]
# [('obj', 'http://www.wikidata.org/entity/Q1789102'), ('name', 'National Board of Review Award for Best Film')]
# [('obj', 'http://www.wikidata.org/entity/Q23958341'), ('name', 'President of the Jury at the Cannes Festival')]
# [('obj', 'http://www.wikidata.org/entity/Q974693'), ('name', 'Italian American')]
# [('obj', 'http://www.wikidata.org/entity/Q1075293'), ('name', 'Irish Americans')]
# [('obj', 'http://www.wikidata.org/entity/Q185582'), ('name', 'Knoxville')]
# [('obj', 'http://www.wikidata.org/entity/Q51581'), ('name', 'Howard Hawks')]
# [('obj', 'http://www.wikidata.org/entity/Q41375'), ('name', 'BAFTA Award for Best Original Screenplay')]
# [('obj', 'http://www.wikidata.org/entity/Q849124'), ('name', 'Golden Globe Award for Best Screenplay')]
# [('obj', 'http://www.wikidata.org/entity/Q93439'), ('name', '52nd Golden Globe Awards')]
# [('obj', 'http://www.wikidata.org/entity/Q459290'), ('name', 'independent film')]
# [('obj', 'http://www.wikidata.org/entity/Q1158484'), ('name', 'Quentin')]
# [('obj', 'http://www.wikidata.org/entity/Q21487819'), ('name', 'Tarantino')]
# [('obj', 'http://www.wikidata.org/entity/Q3404975'), ('name', 'Lumière Award, Lyon Festival of cinema')]
# [('obj', 'http://www.wikidata.org/entity/Q245949'), ('name', '36th César Awards')]
# [('obj', 'http://www.wikidata.org/entity/Q32947601'), ('name', 'Daniella Pick')]
# [('obj', 'http://www.wikidata.org/entity/Q2690424'), ('name', '66th British Academy Film Awards')]
# [('obj', 'http://www.wikidata.org/entity/Q5274115'), ('name', 'Didem Erol')]
# 50

# %%
# write your queries
# [('obj', 'http://www.wikidata.org/entity/Q3455803'), ('name', 'director')]
queryString = """
SELECT DISTINCT ?obj ?name
WHERE {
   # bind something
   wd:Q3455803 ?p ?obj .
   # get the label
   # ?obj sc:name ?name.
}
LIMIT 50
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('obj', 'http://www.wikidata.org/entity/Q5870903'), ('name', 'Category:Directors')]
# [('obj', 'http://www.wikidata.org/entity/Q28640'), ('name', 'profession')]
# [('obj', 'http://www.wikidata.org/entity/Q483501'), ('name', 'artist')]
# [('obj', 'http://www.wikidata.org/entity/Q2137554'), ('name', 'direction')]
# [('obj', 'http://www.wikidata.org/entity/Q2462658'), ('name', 'manager')]
# [('obj', 'http://www.wikidata.org/entity/Q2500638'), ('name', 'creator')]
# [('obj', 'http://www.wikidata.org/entity/Q2607241'), ('name', 'mise en scène')]
# [('obj', 'http://www.wikidata.org/entity/Q8104450'), ('name', 'Category:Wikipedia categories named after filmmakers')]
# [('obj', 'http://www.wikidata.org/entity/P57'), ('name', 'director')]
# [('obj', 'http://www.wikidata.org/entity/Q10809861'), ('name', 'Template:Infobox film director')]
# 10

# %%
# write your queries
# [('obj', 'http://www.wikidata.org/entity/Q3455803'), ('name', 'director')]
# let's try to search predicates of director
queryString = """
SELECT DISTINCT ?p ?name
WHERE {
   # bind something
   wd:Q3455803 ?p ?obj .
   # get the label
   # ?p sc:name ?name.
}
LIMIT 50
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P918'), ('name', 'NOC Occupation Code')]
# [('p', 'http://www.wikidata.org/prop/direct/P101'), ('name', 'field of work')]
# [('p', 'http://www.wikidata.org/prop/direct/P1245'), ('name', 'OmegaWiki Defined Meaning')]
# [('p', 'http://www.wikidata.org/prop/direct/P1424'), ('name', "topic's main template")]
# [('p', 'http://www.wikidata.org/prop/direct/P1687'), ('name', 'Wikidata property')]
# [('p', 'http://www.wikidata.org/prop/direct/P227'), ('name', 'GND ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2671'), ('name', 'Google Knowledge Graph ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('name', 'subclass of')]
# [('p', 'http://www.wikidata.org/prop/direct/P2888'), ('name', 'exact match')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('name', 'instance of')]
# [('p', 'http://www.wikidata.org/prop/direct/P3553'), ('name', 'Zhihu topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P373'), ('name', 'Commons category')]
# [('p', 'http://www.wikidata.org/prop/direct/P425'), ('name', 'field of this occupation')]
# [('p', 'http://www.wikidata.org/prop/direct/P4801'), ('name', 'LoC and MARC vocabularies ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6186'), ('name', 'category for eponymous categories')]
# [('p', 'http://www.wikidata.org/prop/direct/P6573'), ('name', 'Klexikon article ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8814'), ('name', 'WordNet 3.1 Synset ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P910'), ('name', "topic's main category")]
# [('p', 'http://www.wikidata.org/prop/direct/P973'), ('name', 'described at URL')]
# [('p', 'http://www.wikidata.org/prop/direct/P1043'), ('name', 'IDEO Job ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5188'), ('name', 'Sandbox-Lexeme')]
# 21

# %%
# write your queries
# [('obj', 'http://www.wikidata.org/entity/Q3455803'), ('name', 'director')]
queryString = """
SELECT DISTINCT ?obj ?name
WHERE {
   # bind something
   wd:Q3455803 ?p ?obj .
   # get the label
   # ?obj sc:name ?name.
}
LIMIT 50
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('obj', 'http://www.wikidata.org/entity/Q5870903'), ('name', 'Category:Directors')]
# [('obj', 'http://www.wikidata.org/entity/Q28640'), ('name', 'profession')]
# [('obj', 'http://www.wikidata.org/entity/Q483501'), ('name', 'artist')]
# [('obj', 'http://www.wikidata.org/entity/Q2137554'), ('name', 'direction')]
# [('obj', 'http://www.wikidata.org/entity/Q2462658'), ('name', 'manager')]
# [('obj', 'http://www.wikidata.org/entity/Q2500638'), ('name', 'creator')]
# [('obj', 'http://www.wikidata.org/entity/Q2607241'), ('name', 'mise en scène')]
# [('obj', 'http://www.wikidata.org/entity/Q8104450'), ('name', 'Category:Wikipedia categories named after filmmakers')]
# [('obj', 'http://www.wikidata.org/entity/P57'), ('name', 'director')]
# [('obj', 'http://www.wikidata.org/entity/Q10809861'), ('name', 'Template:Infobox film director')]
# 10

# %%
# write your queries
# [('obj', 'http://www.wikidata.org/entity/Q3455803'), ('name', 'director')]
queryString = """
SELECT DISTINCT ?obj ?name
WHERE {
   # bind something
   wd:Q971865 wdt:P57 ?obj .
   # get the label
   # ?obj sc:name ?name.
}
LIMIT 50
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('obj', 'http://www.wikidata.org/entity/Q25089'), ('name', 'Woody Allen')]
# [('obj', 'http://www.wikidata.org/entity/Q27351'), ('name', 'Senkichi Taniguchi')]
# 2

# %%
# write your queries
# try to find predicate that link with film "What's Up, Tiger Lily? " to Senkichi Taniguchi and Woody Allen
queryString = """
SELECT DISTINCT ?p ?pName
WHERE {
   # bind something
   wd:Q971865 ?p wd:Q27351 ;
        # ?p wd:Q25089 .
   # get the label
   # ?p sc:name ?pName.
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P57'), ('pName', 'director')]
# 1

# %%
# let's try with subclass of film director
# filter by 'director'
queryString = """
SELECT DISTINCT ?obj ?objName
WHERE {
   # bind something
   wd:Q2526255 wdt:P279 ?obj .
   # get the label
   # ?obj sc:name ?objName.
   FILTER REGEX (?objName, "director")
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# The operation failed timed out

# %% [markdown]
# Final query for this task

# %%
# Final query
queryString = """
SELECT DISTINCT ?obj ?objName
WHERE {
   # bind something
   wd:Q2526255 wdt:P279 ?obj .
   # get the label
   # ?obj sc:name ?objName.
   FILTER REGEX (?objName, "director")
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('obj', 'http://www.wikidata.org/entity/Q3455803'), ('objName', 'director')]
# 1

# %% [markdown]
# ## Task 3
# Identify the BGP for film genre

# %%
# write your queries
# find properties
queryString = """
SELECT DISTINCT ?p ?name
WHERE {
   # bind something
   wd:Q25089 ?p ?obj .
   # get the label
   # ?p sc:name ?name.
}
LIMIT 50
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P1003'), ('name', 'National Library of Romania ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1005'), ('name', 'Portuguese National Library ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1006'), ('name', 'Nationale Thesaurus voor Auteurs ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1015'), ('name', 'NORAF ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P103'), ('name', 'native language')]
# [('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('p', 'http://www.wikidata.org/prop/direct/P108'), ('name', 'employer')]
# [('p', 'http://www.wikidata.org/prop/direct/P109'), ('name', 'signature')]
# [('p', 'http://www.wikidata.org/prop/direct/P1150'), ('name', 'Regensburg Classification')]
# [('p', 'http://www.wikidata.org/prop/direct/P1207'), ('name', 'NUKAT ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1220'), ('name', 'Internet Broadway Database person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1233'), ('name', 'Internet Speculative Fiction Database author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1263'), ('name', 'NNDB people ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1266'), ('name', 'AlloCiné person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1273'), ('name', 'CANTIC ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1280'), ('name', 'CONOR.SI ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1283'), ('name', 'filmography')]
# [('p', 'http://www.wikidata.org/prop/direct/P1284'), ('name', 'Munzinger person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1296'), ('name', 'Gran Enciclopèdia Catalana ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1303'), ('name', 'instrument')]
# [('p', 'http://www.wikidata.org/prop/direct/P1309'), ('name', 'EGAXA ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1315'), ('name', 'NLA Trove ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1317'), ('name', 'floruit')]
# [('p', 'http://www.wikidata.org/prop/direct/P1343'), ('name', 'described by source')]
# [('p', 'http://www.wikidata.org/prop/direct/P1368'), ('name', 'LNB ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1375'), ('name', 'NSK ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P138'), ('name', 'named after')]
# [('p', 'http://www.wikidata.org/prop/direct/P1411'), ('name', 'nominated for')]
# [('p', 'http://www.wikidata.org/prop/direct/P1412'), ('name', 'languages spoken, written or signed')]
# [('p', 'http://www.wikidata.org/prop/direct/P1417'), ('name', 'Encyclopædia Britannica Online ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1455'), ('name', 'list of works')]
# [('p', 'http://www.wikidata.org/prop/direct/P1477'), ('name', 'birth name')]
# [('p', 'http://www.wikidata.org/prop/direct/P1559'), ('name', 'name in native language')]
# [('p', 'http://www.wikidata.org/prop/direct/P1580'), ('name', 'University of Barcelona authority ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1607'), ('name', 'Dialnet author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P166'), ('name', 'award received')]
# [('p', 'http://www.wikidata.org/prop/direct/P1695'), ('name', 'NLP ID (unique)')]
# [('p', 'http://www.wikidata.org/prop/direct/P172'), ('name', 'ethnic group')]
# [('p', 'http://www.wikidata.org/prop/direct/P1728'), ('name', 'AllMusic artist ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1741'), ('name', 'GTAA ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P18'), ('name', 'image')]
# [('p', 'http://www.wikidata.org/prop/direct/P1816'), ('name', 'National Portrait Gallery (London) person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1819'), ('name', 'genealogics.org person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P19'), ('name', 'place of birth')]
# [('p', 'http://www.wikidata.org/prop/direct/P1953'), ('name', 'Discogs artist ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1969'), ('name', 'MovieMeter director ID (former scheme)')]
# [('p', 'http://www.wikidata.org/prop/direct/P1977'), ('name', 'Les Archives du Spectacle Person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2019'), ('name', 'AllMovie person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2031'), ('name', 'work period (start)')]
# [('p', 'http://www.wikidata.org/prop/direct/P21'), ('name', 'sex or gender')]
# 50

# %%
# write your queries
# find objects of director Woody Allen 
queryString = """
SELECT DISTINCT ?obj ?name
WHERE {
   # bind something
   wd:Q25089 ?p ?obj .
   # get the label
   # ?obj sc:name ?name.
}
LIMIT 50
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('obj', 'http://www.wikidata.org/entity/Q349357'), ('name', 'Woody Herman')]
# [('obj', 'http://www.wikidata.org/entity/Q1140914'), ('name', 'Soon-Yi Previn')]
# [('obj', 'http://www.wikidata.org/entity/Q22673707'), ('name', 'Bechet Dumaine Allen')]
# [('obj', 'http://www.wikidata.org/entity/Q22673708'), ('name', 'Manzie Tio Allen')]
# [('obj', 'http://www.wikidata.org/entity/Q18426'), ('name', 'The Bronx')]
# [('obj', 'http://www.wikidata.org/entity/Q102642'), ('name', 'Diane Keaton')]
# [('obj', 'http://www.wikidata.org/entity/Q3404523'), ('name', 'David di Donatello for Best Foreign Actor')]
# [('obj', 'http://www.wikidata.org/entity/Q599316'), ('name', 'New School')]
# [('obj', 'http://www.wikidata.org/entity/Q19961034'), ('name', 'Woody')]
# [('obj', 'http://www.wikidata.org/entity/Q206124'), ('name', 'Midnight in Paris')]
# [('obj', 'http://www.wikidata.org/entity/Q3831197'), ('name', 'Letty Aronson')]
# [('obj', 'http://www.wikidata.org/entity/Q31579'), ('name', 'David di Donatello')]
# [('obj', 'http://www.wikidata.org/entity/Q3241784'), ('name', 'Golden Lion for Lifetime Achievements')]
# [('obj', 'http://www.wikidata.org/entity/Q50616934'), ('name', 'honorary doctorate of Pompeu Fabra University')]
# [('obj', 'http://www.wikidata.org/entity/Q3404587'), ('name', 'FIPRESCI Prize of the Festival de Cannes')]
# [('obj', 'http://www.wikidata.org/entity/Q2455835'), ('name', 'Woody Allen filmography')]
# [('obj', 'http://www.wikidata.org/entity/Q971865'), ('name', "What's Up, Tiger Lily?")]
# [('obj', 'http://www.wikidata.org/entity/Q3822438'), ('name', 'Butaca Awards')]
# [('obj', 'http://www.wikidata.org/entity/Q103360'), ('name', 'Academy Award for Best Director')]
# [('obj', 'http://www.wikidata.org/entity/Q10800557'), ('name', 'film actor')]
# [('obj', 'http://www.wikidata.org/entity/Q13452531'), ('name', 'Commandeur des Arts et des Lettres\u200e')]
# [('obj', 'http://www.wikidata.org/entity/Q139184'), ('name', 'BAFTA Award for Best Film')]
# [('obj', 'http://www.wikidata.org/entity/Q15981151'), ('name', 'jazz musician')]
# [('obj', 'http://www.wikidata.org/entity/Q174389'), ('name', 'César Award')]
# [('obj', 'http://www.wikidata.org/entity/Q1860'), ('name', 'English')]
# [('obj', 'http://www.wikidata.org/entity/Q18844224'), ('name', 'science fiction writer')]
# [('obj', 'http://www.wikidata.org/entity/Q188740'), ('name', 'Museum of Modern Art')]
# [('obj', 'http://www.wikidata.org/entity/Q1930187'), ('name', 'journalist')]
# [('obj', 'http://www.wikidata.org/entity/Q214917'), ('name', 'playwright')]
# [('obj', 'http://www.wikidata.org/entity/Q245068'), ('name', 'comedian')]
# [('obj', 'http://www.wikidata.org/entity/Q2526255'), ('name', 'film director')]
# [('obj', 'http://www.wikidata.org/entity/Q2648323'), ('name', 'Allen')]
# [('obj', 'http://www.wikidata.org/entity/Q28389'), ('name', 'screenwriter')]
# [('obj', 'http://www.wikidata.org/entity/Q288928'), ('name', 'agnosticism')]
# [('obj', 'http://www.wikidata.org/entity/Q30'), ('name', 'United States of America')]
# [('obj', 'http://www.wikidata.org/entity/Q3282637'), ('name', 'film producer')]
# [('obj', 'http://www.wikidata.org/entity/Q36180'), ('name', 'writer')]
# [('obj', 'http://www.wikidata.org/entity/Q36834'), ('name', 'composer')]
# [('obj', 'http://www.wikidata.org/entity/Q41417'), ('name', 'Academy Award for Best Writing, Original Screenplay')]
# [('obj', 'http://www.wikidata.org/entity/Q463303'), ('name', 'American Academy of Arts and Sciences')]
# [('obj', 'http://www.wikidata.org/entity/Q482980'), ('name', 'author')]
# [('obj', 'http://www.wikidata.org/entity/Q5'), ('name', 'human')]
# [('obj', 'http://www.wikidata.org/entity/Q52382875'), ('name', 'AAAS Fellow')]
# [('obj', 'http://www.wikidata.org/entity/Q58488719'), ('name', 'Billy Ireland Cartoon Library & Museum biographical files')]
# [('obj', 'http://www.wikidata.org/entity/Q639669'), ('name', 'musician')]
# [('obj', 'http://www.wikidata.org/entity/Q6581097'), ('name', 'male')]
# [('obj', 'http://www.wikidata.org/entity/Q67311526'), ('name', 'Obalky knih.cz')]
# [('obj', 'http://www.wikidata.org/entity/Q708135'), ('name', 'Silver Bear')]
# [('obj', 'http://www.wikidata.org/entity/Q73555012'), ('name', 'works protected by copyrights')]
# [('obj', 'http://www.wikidata.org/entity/Q787148'), ('name', 'Academy Fellowship Award')]
# 50

# %%
# write your queries
# find objects of director Woody Allen
# [('obj', 'http://www.wikidata.org/entity/Q971865'), ('name', "What's Up, Tiger Lily?")]
queryString = """
SELECT DISTINCT ?obj ?name
WHERE {
   # bind something
   wd:Q971865 ?p ?obj .
   # get the label
   # ?obj sc:name ?name.
}
LIMIT 50
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('obj', 'http://www.wikidata.org/entity/Q25089'), ('name', 'Woody Allen')]
# [('obj', 'http://www.wikidata.org/entity/Q465224'), ('name', 'American International Pictures')]
# [('obj', 'http://www.wikidata.org/entity/Q376138'), ('name', 'Charles H. Joffe')]
# [('obj', 'http://www.wikidata.org/entity/Q6381680'), ('name', 'Kazuo Yamada')]
# [('obj', 'http://www.wikidata.org/entity/Q1053608'), ('name', "The Lovin' Spoonful")]
# [('obj', 'http://www.wikidata.org/entity/Q11424'), ('name', 'film')]
# [('obj', 'http://www.wikidata.org/entity/Q17'), ('name', 'Japan')]
# [('obj', 'http://www.wikidata.org/entity/Q1860'), ('name', 'English')]
# [('obj', 'http://www.wikidata.org/entity/Q22006653'), ('name', 'color')]
# [('obj', 'http://www.wikidata.org/entity/Q2297927'), ('name', 'spy film')]
# [('obj', 'http://www.wikidata.org/entity/Q30'), ('name', 'United States of America')]
# [('obj', 'http://www.wikidata.org/entity/Q723685'), ('name', 'video on demand')]
# [('obj', 'http://www.wikidata.org/entity/Q907311'), ('name', 'Netflix')]
# [('obj', 'http://www.wikidata.org/entity/Q20644797'), ('name', 'FSK 16')]
# [('obj', 'http://www.wikidata.org/entity/Q875920'), ('name', 'Toho')]
# [('obj', 'http://www.wikidata.org/entity/Q271861'), ('name', 'Akiko Wakabayashi')]
# [('obj', 'http://www.wikidata.org/entity/Q967761'), ('name', 'John Sebastian')]
# [('obj', 'http://www.wikidata.org/entity/Q12270304'), ('name', 'Mickey Rose')]
# [('obj', 'http://www.wikidata.org/entity/Q273532'), ('name', 'Louise Lasser')]
# [('obj', 'http://www.wikidata.org/entity/Q27351'), ('name', 'Senkichi Taniguchi')]
# [('obj', 'http://www.wikidata.org/entity/Q11356032'), ('name', 'Tatsuya Mihashi')]
# [('obj', 'http://www.wikidata.org/entity/Q3751773'), ('name', 'Frank Buxton')]
# [('obj', 'http://www.wikidata.org/entity/Q3674850'), ('name', 'China Lee')]
# [('obj', 'http://www.wikidata.org/entity/Q449493'), ('name', 'Mie Hama')]
# [('obj', 'http://www.wikidata.org/entity/Q3189161'), ('name', 'Julie Bennett')]
# 25

# %%
# write your queries
# find properties of film 'What's Up, Tiger Lily?'
# [('obj', 'http://www.wikidata.org/entity/Q971865'), ('name', "What's Up, Tiger Lily?")]
queryString = """
SELECT DISTINCT ?p ?name
WHERE {
   # bind something
   wd:Q971865 ?p ?obj .
   # get the label
   # ?p sc:name ?name.
}
LIMIT 50
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P1237'), ('name', 'Box Office Mojo film ID (former scheme)')]
# [('p', 'http://www.wikidata.org/prop/direct/P1258'), ('name', 'Rotten Tomatoes ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1265'), ('name', 'AlloCiné film ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P136'), ('name', 'genre')]
# [('p', 'http://www.wikidata.org/prop/direct/P1417'), ('name', 'Encyclopædia Britannica Online ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1476'), ('name', 'title')]
# [('p', 'http://www.wikidata.org/prop/direct/P1562'), ('name', 'AllMovie title ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P161'), ('name', 'cast member')]
# [('p', 'http://www.wikidata.org/prop/direct/P162'), ('name', 'producer')]
# [('p', 'http://www.wikidata.org/prop/direct/P1712'), ('name', 'Metacritic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P175'), ('name', 'performer')]
# [('p', 'http://www.wikidata.org/prop/direct/P1874'), ('name', 'Netflix ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1970'), ('name', 'MovieMeter film ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1981'), ('name', 'FSK film rating')]
# [('p', 'http://www.wikidata.org/prop/direct/P2047'), ('name', 'duration')]
# [('p', 'http://www.wikidata.org/prop/direct/P214'), ('name', 'VIAF ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2334'), ('name', 'Swedish Film Database film ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2346'), ('name', 'Elonet movie ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P244'), ('name', 'Library of Congress authority ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2529'), ('name', 'ČSFD film ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2603'), ('name', 'Kinopoisk film ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2631'), ('name', 'TCM Movie Database film ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2638'), ('name', 'TV.com ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2704'), ('name', 'EIDR content ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P272'), ('name', 'production company')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('name', 'instance of')]
# [('p', 'http://www.wikidata.org/prop/direct/P3107'), ('name', 'LdiF ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3129'), ('name', 'cine.gr film ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3138'), ('name', 'OFDb film ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3143'), ('name', 'elFilm film ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3203'), ('name', 'Ciné-Ressources film ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3212'), ('name', 'ISAN')]
# [('p', 'http://www.wikidata.org/prop/direct/P344'), ('name', 'director of photography')]
# [('p', 'http://www.wikidata.org/prop/direct/P345'), ('name', 'IMDb ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3593'), ('name', 'AFI Catalog of Feature Films ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P364'), ('name', 'original language of film or TV show')]
# [('p', 'http://www.wikidata.org/prop/direct/P3804'), ('name', 'TV Guide show ID (former scheme)')]
# [('p', 'http://www.wikidata.org/prop/direct/P3844'), ('name', 'Deutsche Synchronkartei film ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3933'), ('name', 'Cinema.de ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P436'), ('name', 'MusicBrainz release group ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P437'), ('name', 'distribution format')]
# [('p', 'http://www.wikidata.org/prop/direct/P4529'), ('name', 'Douban film ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P462'), ('name', 'color')]
# [('p', 'http://www.wikidata.org/prop/direct/P480'), ('name', 'FilmAffinity ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P4947'), ('name', 'TMDb movie ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P495'), ('name', 'country of origin')]
# [('p', 'http://www.wikidata.org/prop/direct/P5032'), ('name', 'Filmweb.pl film ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5099'), ('name', 'Il mondo dei doppiatori ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P57'), ('name', 'director')]
# [('p', 'http://www.wikidata.org/prop/direct/P577'), ('name', 'publication date')]
# 50

# %%
# write your queries
# find properties of Q971865
# [('obj', 'http://www.wikidata.org/entity/Q971865'), ('name', "What's Up, Tiger Lily?")]
# [('p', 'http://www.wikidata.org/prop/direct/P136'), ('name', 'genre')]
queryString = """
SELECT DISTINCT ?obj ?name
WHERE {
   # bind something
   wd:Q971865 wdt:P136 ?obj .
   # get the label
   # ?obj sc:name ?name.
}
LIMIT 50
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('obj', 'http://www.wikidata.org/entity/Q2297927'), ('name', 'spy film')]
# 1

# %%
# write your queries
# find properties of Q971865
# [('obj', 'http://www.wikidata.org/entity/Q971865'), ('name', "What's Up, Tiger Lily?")]
# [('p', 'http://www.wikidata.org/prop/direct/P136'), ('name', 'genre')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('name', 'instance of')]
queryString = """
SELECT DISTINCT ?obj ?name
WHERE {
   # bind something
   wd:Q971865 wdt:P136 ?genre .
   # ?genre wdt:P31 ?obj .
   # get the label
   # ?obj sc:name ?name.
}
LIMIT 50
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('obj', 'http://www.wikidata.org/entity/Q201658'), ('name', 'film genre')]
# 1

# %% [markdown]
# Final query for this task

# %%
# # write your final query
# find properties of Q971865
# [('obj', 'http://www.wikidata.org/entity/Q971865'), ('name', "What's Up, Tiger Lily?")]
# [('p', 'http://www.wikidata.org/prop/direct/P136'), ('name', 'genre')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('name', 'instance of')]
queryString = """
SELECT DISTINCT ?obj ?name
WHERE {
   # bind something
   wd:Q971865 wdt:P136 ?genre .
   # ?genre wdt:P31 ?obj .
   # get the label
   # ?obj sc:name ?name.
}
LIMIT 50
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('obj', 'http://www.wikidata.org/entity/Q201658'), ('name', 'film genre')]
# 1

# %% [markdown]
# ## Task 4
# Find how many western films are been released in each european country from 2010-01-01 to 2015-31-12 (the result set must be country IRI, label and #films).

# %%
# write your queries
#[('p', 'http://www.wikidata.org/prop/direct/P27'), ('name', 'country of citizenship')]
#[('p', 'http://www.wikidata.org/prop/direct/P30'), ('name', 'continent')]
#[('obj', 'http://www.wikidata.org/entity/Q46'), ('name', 'Europe')]
queryString = """
SELECT DISTINCT ?films ?sName ?country ?name
WHERE {
   # bind something
   # ?films wdt:P31 wd:Q5;
           wdt:P136 wd:Q172980;
           wdt:P27 ?country.
           
   # ?country wdt:P31 wd:Q6256; 
           wdt:P30 wd:Q46.        
           
   # get the label
   # ?films sc:name ?sName .
   # ?country sc:name ?name .
   
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('films', 'http://www.wikidata.org/entity/Q309240'), ('sName', 'Jean Giraud'), ('country', 'http://www.wikidata.org/entity/Q142'), ('name', 'France')]
# 1

# %%
# write your queries
# film genre (Q201658)
queryString = """
SELECT DISTINCT ?s ?sName
WHERE {
   # bind something
   # ?s wdt:P31 wd:Q201658 .
   # get the label
   # ?s sc:name ?sName.
   FILTER REGEX(?sName, "western")
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('s', 'http://www.wikidata.org/entity/Q212781'), ('sName', 'spaghetti western')]
# [('s', 'http://www.wikidata.org/entity/Q4836991'), ('sName', 'B western')]
# [('s', 'http://www.wikidata.org/entity/Q83646243'), ('sName', 'western animation')]
# [('s', 'http://www.wikidata.org/entity/Q78528852'), ('sName', 'neo-western')]
# 4

# %%
# write your queries
# film genre (Q201658)
queryString = """
SELECT DISTINCT ?genre ?genreName
WHERE {
   # bind something
   # ?s wdt:P136 ?genre .
   # get the label
   # ?genre sc:name ?genreName
   FILTER REGEX(?genreName, ".*Western.*")
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('genre', 'http://www.wikidata.org/entity/Q26263265'), ('genreName', 'Western art')]
# [('genre', 'http://www.wikidata.org/entity/Q4235011'), ('genreName', 'Space Western')]
# [('genre', 'http://www.wikidata.org/entity/Q9730'), ('genreName', 'Western classical music')]
# [('genre', 'http://www.wikidata.org/entity/Q172980'), ('genreName', 'Western film')]
# [('genre', 'http://www.wikidata.org/entity/Q491158'), ('genreName', 'Revisionist Western')]
# [('genre', 'http://www.wikidata.org/entity/Q12197074'), ('genreName', 'Western novel')]
# [('genre', 'http://www.wikidata.org/entity/Q367591'), ('genreName', 'Western literature')]
# [('genre', 'http://www.wikidata.org/entity/Q7439349'), ('genreName', 'Scrumpy and Western')]
# [('genre', 'http://www.wikidata.org/entity/Q21590660'), ('genreName', 'Western')]
# [('genre', 'http://www.wikidata.org/entity/Q1425111'), ('genreName', 'Western music (country)')]
# [('genre', 'http://www.wikidata.org/entity/Q3756540'), ('genreName', 'Western painting')]
# [('genre', 'http://www.wikidata.org/entity/Q1730388'), ('genreName', 'Western swing')]
# [('genre', 'http://www.wikidata.org/entity/Q3111140'), ('genreName', 'Gulf and Western Industries')]
# [('genre', 'http://www.wikidata.org/entity/Q1057354'), ('genreName', 'Western comics')]
# [('genre', 'http://www.wikidata.org/entity/Q2719078'), ('genreName', 'Western music')]
# [('genre', 'http://www.wikidata.org/entity/Q5100366'), ('genreName', 'Chinese-language Western-style opera')]
# [('genre', 'http://www.wikidata.org/entity/Q248180'), ('genreName', 'Western')]
# [('genre', 'http://www.wikidata.org/entity/Q4674071'), ('genreName', 'Acid Western')]
# 18

# %%
# write your queries
# film genre (Q201658)
# [('genre', 'http://www.wikidata.org/entity/Q172980'), ('genreName', 'Western film')]
queryString = """
SELECT DISTINCT ?film ?filmName
WHERE {
   # bind something
   # ?film wdt:P136 wd:Q172980;
       wdt:P31 wd:Q11424.
       
   # get the label
   # ?film sc:name ?filmName.
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('film', 'http://www.wikidata.org/entity/Q15882802'), ('filmName', 'The Storm')]
# [('film', 'http://www.wikidata.org/entity/Q16200305'), ('filmName', 'Fangs of the Arctic')]
# [('film', 'http://www.wikidata.org/entity/Q17011616'), ('filmName', 'Mr. Texas')]
# [('film', 'http://www.wikidata.org/entity/Q17036710'), ('filmName', 'The Drifting Avenger')]
# [('film', 'http://www.wikidata.org/entity/Q17052173'), ('filmName', 'The Desert of the Lost')]
# [('film', 'http://www.wikidata.org/entity/Q17053125'), ('filmName', 'Between Dangers')]
# [('film', 'http://www.wikidata.org/entity/Q7569044'), ('filmName', 'South of Santa Fe')]
# [('film', 'http://www.wikidata.org/entity/Q17184091'), ('filmName', 'With Buffalo Bill on the U. P. Trail')]
# [('film', 'http://www.wikidata.org/entity/Q17190227'), ('filmName', 'Easy Going')]
# [('film', 'http://www.wikidata.org/entity/Q17639337'), ('filmName', 'Skedaddle Gold')]
# [('film', 'http://www.wikidata.org/entity/Q17639444'), ('filmName', 'Speedy Spurs')]
# [('film', 'http://www.wikidata.org/entity/Q17639774'), ('filmName', "Tearin' Loose")]
# [('film', 'http://www.wikidata.org/entity/Q17639857'), ('filmName', 'The Fighting Cheat')]
# [('film', 'http://www.wikidata.org/entity/Q17639861'), ('filmName', 'The Flying Buckaroo')]
# [('film', 'http://www.wikidata.org/entity/Q17640027'), ('filmName', 'Thundering Romance')]
# [('film', 'http://www.wikidata.org/entity/Q18153014'), ('filmName', 'The Only Road')]
# [('film', 'http://www.wikidata.org/entity/Q18153242'), ('filmName', 'Prairie Law')]
# [('film', 'http://www.wikidata.org/entity/Q18154990'), ('filmName', 'The Marshal of Mesa City')]
# [('film', 'http://www.wikidata.org/entity/Q18155026'), ('filmName', 'The Outcasts of Poker Flat')]
# [('film', 'http://www.wikidata.org/entity/Q7911233'), ('filmName', 'Valerie')]
# [('film', 'http://www.wikidata.org/entity/Q20949826'), ('filmName', 'Black Hills Express')]
# [('film', 'http://www.wikidata.org/entity/Q20949894'), ('filmName', 'Land Beyond the Law')]
# [('film', 'http://www.wikidata.org/entity/Q20950023'), ('filmName', 'Wyoming')]
# [('film', 'http://www.wikidata.org/entity/Q23090947'), ('filmName', 'The Man from Tumbleweeds')]
# [('film', 'http://www.wikidata.org/entity/Q23306239'), ('filmName', 'Blazing Six Shooters')]
# [('film', 'http://www.wikidata.org/entity/Q18225084'), ('filmName', 'The Hateful Eight')]
# [('film', 'http://www.wikidata.org/entity/Q485336'), ('filmName', 'Tell Them Willie Boy Is Here')]
# [('film', 'http://www.wikidata.org/entity/Q497051'), ('filmName', "Goin' South")]
# [('film', 'http://www.wikidata.org/entity/Q498809'), ('filmName', 'Tickle Me')]
# [('film', 'http://www.wikidata.org/entity/Q604424'), ('filmName', 'Stay Away, Joe')]
# [('film', 'http://www.wikidata.org/entity/Q607524'), ('filmName', 'Destry Rides Again')]
# [('film', 'http://www.wikidata.org/entity/Q634325'), ('filmName', 'The Rare Breed')]
# [('film', 'http://www.wikidata.org/entity/Q650539'), ('filmName', 'A Time for Killing')]
# [('film', 'http://www.wikidata.org/entity/Q1742225'), ('filmName', 'Montana Moon')]
# [('film', 'http://www.wikidata.org/entity/Q1759125'), ('filmName', 'My Little Chickadee')]
# [('film', 'http://www.wikidata.org/entity/Q1759875'), ('filmName', 'Valdez Is Coming')]
# [('film', 'http://www.wikidata.org/entity/Q21528206'), ('filmName', 'Vigilantes of Dodge City')]
# [('film', 'http://www.wikidata.org/entity/Q22350815'), ('filmName', 'Beneath Western Skies')]
# [('film', 'http://www.wikidata.org/entity/Q50714'), ('filmName', 'Stagecoach')]
# [('film', 'http://www.wikidata.org/entity/Q128975'), ('filmName', 'The Last Frontier')]
# [('film', 'http://www.wikidata.org/entity/Q247130'), ('filmName', '3:10 to Yuma')]
# [('film', 'http://www.wikidata.org/entity/Q261305'), ('filmName', 'Bite the Bullet')]
# [('film', 'http://www.wikidata.org/entity/Q746029'), ('filmName', '3:10 to Yuma')]
# [('film', 'http://www.wikidata.org/entity/Q15961525'), ('filmName', 'The Homesman')]
# [('film', 'http://www.wikidata.org/entity/Q370252'), ('filmName', 'My Darling Clementine')]
# [('film', 'http://www.wikidata.org/entity/Q481091'), ('filmName', 'Der Kaiser von Kalifornien')]
# [('film', 'http://www.wikidata.org/entity/Q829365'), ('filmName', "Don't Touch the White Woman!")]
# [('film', 'http://www.wikidata.org/entity/Q507588'), ('filmName', 'Arrowhead')]
# [('film', 'http://www.wikidata.org/entity/Q508813'), ('filmName', 'Chimmie Fadden Out West')]
# [('film', 'http://www.wikidata.org/entity/Q512987'), ('filmName', 'Cut-Throats Nine')]
# [('film', 'http://www.wikidata.org/entity/Q521876'), ('filmName', 'Last of the Renegades')]
# [('film', 'http://www.wikidata.org/entity/Q535427'), ('filmName', 'The Desperado Trail')]
# [('film', 'http://www.wikidata.org/entity/Q564124'), ('filmName', 'Apache Gold')]
# [('film', 'http://www.wikidata.org/entity/Q153677'), ('filmName', 'For a Few Dollars More')]
# [('film', 'http://www.wikidata.org/entity/Q642740'), ('filmName', 'Ace of the Saddle')]
# [('film', 'http://www.wikidata.org/entity/Q691611'), ('filmName', 'Serenity')]
# [('film', 'http://www.wikidata.org/entity/Q2252587'), ('filmName', 'Kansas Raiders')]
# [('film', 'http://www.wikidata.org/entity/Q3270280'), ('filmName', 'Gun the Man Down')]
# [('film', 'http://www.wikidata.org/entity/Q3282995'), ('filmName', 'The Guns of Fort Petticoat')]
# [('film', 'http://www.wikidata.org/entity/Q5130876'), ('filmName', 'Clearing the Range')]
# [('film', 'http://www.wikidata.org/entity/Q5148689'), ('filmName', 'Colorado')]
# [('film', 'http://www.wikidata.org/entity/Q5172277'), ('filmName', 'Coroner Creek')]
# [('film', 'http://www.wikidata.org/entity/Q2364343'), ('filmName', 'Destry')]
# [('film', 'http://www.wikidata.org/entity/Q5267318'), ('filmName', 'Devil Riders')]
# [('film', 'http://www.wikidata.org/entity/Q5270936'), ('filmName', 'Diamond Trail')]
# [('film', 'http://www.wikidata.org/entity/Q5281036'), ('filmName', 'Dirty Little Billy')]
# [('film', 'http://www.wikidata.org/entity/Q5889142'), ('filmName', 'Home on the Prairie')]
# [('film', 'http://www.wikidata.org/entity/Q5898966'), ('filmName', 'Hopalong Cassidy Returns')]
# [('film', 'http://www.wikidata.org/entity/Q1257078'), ('filmName', 'Mad Dog Morgan')]
# [('film', 'http://www.wikidata.org/entity/Q6010284'), ('filmName', 'In Old Cheyenne')]
# [('film', 'http://www.wikidata.org/entity/Q6010295'), ('filmName', 'In Old Monterey')]
# [('film', 'http://www.wikidata.org/entity/Q12103918'), ('filmName', 'Brand of the Outlaws')]
# [('film', 'http://www.wikidata.org/entity/Q12125803'), ('filmName', 'Lone Rider')]
# [('film', 'http://www.wikidata.org/entity/Q13548396'), ('filmName', 'Davy Crockett, Indian Scout')]
# [('film', 'http://www.wikidata.org/entity/Q17148722'), ('filmName', 'The Texan')]
# [('film', 'http://www.wikidata.org/entity/Q18709056'), ('filmName', 'Rimrock Jones')]
# [('film', 'http://www.wikidata.org/entity/Q19881241'), ('filmName', 'Texas Rangers Ride Again')]
# [('film', 'http://www.wikidata.org/entity/Q20092059'), ('filmName', 'The Desert Rider')]
# [('film', 'http://www.wikidata.org/entity/Q15629075'), ('filmName', 'Junction City')]
# [('film', 'http://www.wikidata.org/entity/Q20649625'), ('filmName', 'Ride a Crooked Mile')]
# [('film', 'http://www.wikidata.org/entity/Q1198850'), ('filmName', 'The Big Trail')]
# [('film', 'http://www.wikidata.org/entity/Q20814506'), ('filmName', 'Drums of Destiny')]
# [('film', 'http://www.wikidata.org/entity/Q20814641'), ('filmName', 'Men of Texas')]
# [('film', 'http://www.wikidata.org/entity/Q20814801'), ('filmName', 'The Big Trail')]
# [('film', 'http://www.wikidata.org/entity/Q8046967'), ('filmName', 'Yahsi Bati - The Ottoman Cowboys')]
# [('film', 'http://www.wikidata.org/entity/Q1753894'), ('filmName', 'Shalako')]
# [('film', 'http://www.wikidata.org/entity/Q3704222'), ('filmName', 'Dead in Tombstone')]
# [('film', 'http://www.wikidata.org/entity/Q23814892'), ('filmName', 'Riders of the Dawn')]
# [('film', 'http://www.wikidata.org/entity/Q582978'), ('filmName', 'Joe Kidd')]
# [('film', 'http://www.wikidata.org/entity/Q3220909'), ('filmName', 'The Kansan')]
# [('film', 'http://www.wikidata.org/entity/Q20456'), ('filmName', 'Dances with Wolves')]
# [('film', 'http://www.wikidata.org/entity/Q767366'), ('filmName', 'Martyrs of the Alamo')]
# [('film', 'http://www.wikidata.org/entity/Q778709'), ('filmName', 'Extreme Prejudice')]
# [('film', 'http://www.wikidata.org/entity/Q849344'), ('filmName', 'She Wore a Yellow Ribbon')]
# [('film', 'http://www.wikidata.org/entity/Q1132535'), ('filmName', 'Little Big Man')]
# [('film', 'http://www.wikidata.org/entity/Q1150612'), ('filmName', 'The Westerner')]
# [('film', 'http://www.wikidata.org/entity/Q1195538'), ('filmName', 'Man of the West')]
# [('film', 'http://www.wikidata.org/entity/Q1094020'), ('filmName', 'City Slickers')]
# [('film', 'http://www.wikidata.org/entity/Q1211921'), ('filmName', 'The Cowboys')]
# [('film', 'http://www.wikidata.org/entity/Q1217011'), ('filmName', 'Unconquered')]
# 100

# %% [markdown]
# Final query for this task

# %%
# write your final query

# %% [markdown]
# ## Task 5
# Consider only films directed by Woody Allen or Quentin Tarantino. Then consider the date of publication of these films (take the first one if there are more than one date of publication). Return the year with more films release for the two director (the result set must be two elements and for each element there must be present the director IRI, the label of the IRI, the year and the number of films).

# %%
# write your queries
# director (P57)
# film (Q11424)
# Woody Allen (Q25089)
# let's search all the films whom director is Woody Allen
queryString = """
SELECT DISTINCT ?film ?filmName
WHERE {
   # bind something
   # ?film wdt:P57 wd:Q25089;
       wdt:P31 wd:Q11424 .
   # get the label
   # ?film sc:name ?filmName.
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('film', 'http://www.wikidata.org/entity/Q3986392'), ('filmName', 'The Concert for New York City')]
# [('film', 'http://www.wikidata.org/entity/Q206124'), ('filmName', 'Midnight in Paris')]
# [('film', 'http://www.wikidata.org/entity/Q682262'), ('filmName', 'Alice')]
# [('film', 'http://www.wikidata.org/entity/Q971865'), ('filmName', "What's Up, Tiger Lily?")]
# [('film', 'http://www.wikidata.org/entity/Q1004531'), ('filmName', 'Bullets Over Broadway')]
# [('film', 'http://www.wikidata.org/entity/Q1354109'), ('filmName', 'Mighty Aphrodite')]
# [('film', 'http://www.wikidata.org/entity/Q729026'), ('filmName', 'Broadway Danny Rose')]
# [('film', 'http://www.wikidata.org/entity/Q733677'), ('filmName', 'Match Point')]
# [('film', 'http://www.wikidata.org/entity/Q740143'), ('filmName', 'Husbands and Wives')]
# [('film', 'http://www.wikidata.org/entity/Q806092'), ('filmName', 'Bananas')]
# [('film', 'http://www.wikidata.org/entity/Q1321004'), ('filmName', 'You Will Meet a Tall Dark Stranger')]
# [('film', 'http://www.wikidata.org/entity/Q14511869'), ('filmName', 'Magic in the Moonlight')]
# [('film', 'http://www.wikidata.org/entity/Q614009'), ('filmName', 'Anything Else')]
# [('film', 'http://www.wikidata.org/entity/Q187423'), ('filmName', 'Zelig')]
# [('film', 'http://www.wikidata.org/entity/Q27703144'), ('filmName', 'Wonder Wheel')]
# [('film', 'http://www.wikidata.org/entity/Q786585'), ('filmName', 'Sweet and Lowdown')]
# [('film', 'http://www.wikidata.org/entity/Q1052826'), ('filmName', 'Celebrity')]
# [('film', 'http://www.wikidata.org/entity/Q1218888'), ('filmName', 'Love and Death')]
# [('film', 'http://www.wikidata.org/entity/Q181555'), ('filmName', 'Crimes and Misdemeanors')]
# [('film', 'http://www.wikidata.org/entity/Q682002'), ('filmName', 'scoop')]
# [('film', 'http://www.wikidata.org/entity/Q653518'), ('filmName', 'Stardust Memories')]
# [('film', 'http://www.wikidata.org/entity/Q977372'), ('filmName', 'New York Stories')]
# [('film', 'http://www.wikidata.org/entity/Q65552643'), ('filmName', "Rifkin's Festival")]
# [('film', 'http://www.wikidata.org/entity/Q750003'), ('filmName', 'Sleeper')]
# [('film', 'http://www.wikidata.org/entity/Q610163'), ('filmName', 'Small Time Crooks')]
# [('film', 'http://www.wikidata.org/entity/Q910523'), ('filmName', 'Shadows and Fog')]
# [('film', 'http://www.wikidata.org/entity/Q1133277'), ('filmName', 'Manhattan Murder Mystery')]
# [('film', 'http://www.wikidata.org/entity/Q1146315'), ('filmName', 'Take the Money and Run')]
# [('film', 'http://www.wikidata.org/entity/Q1354121'), ('filmName', 'Melinda and Melinda')]
# [('film', 'http://www.wikidata.org/entity/Q2907178'), ('filmName', 'Blue Jasmine')]
# [('film', 'http://www.wikidata.org/entity/Q731310'), ('filmName', 'Manhattan')]
# [('film', 'http://www.wikidata.org/entity/Q833530'), ('filmName', "Cassandra's Dream")]
# [('film', 'http://www.wikidata.org/entity/Q499697'), ('filmName', 'Everything You Always Wanted to Know About Sex*')]
# [('film', 'http://www.wikidata.org/entity/Q912729'), ('filmName', 'The Purple Rose of Cairo')]
# [('film', 'http://www.wikidata.org/entity/Q1770003'), ('filmName', 'September')]
# [('film', 'http://www.wikidata.org/entity/Q692208'), ('filmName', 'Whatever Works')]
# [('film', 'http://www.wikidata.org/entity/Q17417520'), ('filmName', 'Irrational Man')]
# [('film', 'http://www.wikidata.org/entity/Q29658'), ('filmName', 'To Rome with Love')]
# [('film', 'http://www.wikidata.org/entity/Q20950014'), ('filmName', 'Café Society')]
# [('film', 'http://www.wikidata.org/entity/Q1306629'), ('filmName', "A Midsummer Night's Sex Comedy")]
# [('film', 'http://www.wikidata.org/entity/Q541185'), ('filmName', 'Another Woman')]
# [('film', 'http://www.wikidata.org/entity/Q685109'), ('filmName', 'Radio Days')]
# [('film', 'http://www.wikidata.org/entity/Q42307699'), ('filmName', 'A Rainy Day in New York')]
# [('film', 'http://www.wikidata.org/entity/Q1334572'), ('filmName', 'Everyone Says I Love You')]
# [('film', 'http://www.wikidata.org/entity/Q212123'), ('filmName', 'Vicky Cristina Barcelona')]
# [('film', 'http://www.wikidata.org/entity/Q233464'), ('filmName', 'Annie Hall')]
# [('film', 'http://www.wikidata.org/entity/Q335508'), ('filmName', 'The Curse of the Jade Scorpion')]
# [('film', 'http://www.wikidata.org/entity/Q551762'), ('filmName', 'Deconstructing Harry')]
# [('film', 'http://www.wikidata.org/entity/Q582021'), ('filmName', 'Hollywood Ending')]
# [('film', 'http://www.wikidata.org/entity/Q845057'), ('filmName', 'Hannah and Her Sisters')]
# [('film', 'http://www.wikidata.org/entity/Q961403'), ('filmName', 'Interiors')]
# 51

# %%
# write your queries
# director (P57)
# film (Q11424)
# Woody Allen (Q25089)
# let's search all the films whom director is Woody Allen
# let's find publication year of each film
queryString = """
SELECT DISTINCT ?film ?filmName ?year
WHERE {
   # bind something
   # ?film wdt:P57 wd:Q25089;
       wdt:P31 wd:Q11424 ;
       wdt:P577 ?year.
   # get the label
   # ?film sc:name ?filmName.
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('film', 'http://www.wikidata.org/entity/Q3986392'), ('filmName', 'The Concert for New York City'), ('year', '2001-01-01T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q206124'), ('filmName', 'Midnight in Paris'), ('year', '2011-01-01T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q206124'), ('filmName', 'Midnight in Paris'), ('year', '2011-08-18T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q682262'), ('filmName', 'Alice'), ('year', '1990-01-01T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q682262'), ('filmName', 'Alice'), ('year', '1991-02-28T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q971865'), ('filmName', "What's Up, Tiger Lily?"), ('year', '1966-01-01T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q1004531'), ('filmName', 'Bullets Over Broadway'), ('year', '1994-09-16T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q1004531'), ('filmName', 'Bullets Over Broadway'), ('year', '1995-04-20T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q1354109'), ('filmName', 'Mighty Aphrodite'), ('year', '1995-01-01T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q1354109'), ('filmName', 'Mighty Aphrodite'), ('year', '1996-08-15T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q729026'), ('filmName', 'Broadway Danny Rose'), ('year', '1984-01-01T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q729026'), ('filmName', 'Broadway Danny Rose'), ('year', '1984-08-17T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q733677'), ('filmName', 'Match Point'), ('year', '2005-05-12T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q733677'), ('filmName', 'Match Point'), ('year', '2005-12-29T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q740143'), ('filmName', 'Husbands and Wives'), ('year', '1992-01-01T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q740143'), ('filmName', 'Husbands and Wives'), ('year', '1993-02-25T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q806092'), ('filmName', 'Bananas'), ('year', '1971-01-01T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q806092'), ('filmName', 'Bananas'), ('year', '1974-08-30T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q1321004'), ('filmName', 'You Will Meet a Tall Dark Stranger'), ('year', '2010-01-01T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q1321004'), ('filmName', 'You Will Meet a Tall Dark Stranger'), ('year', '2010-12-02T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q14511869'), ('filmName', 'Magic in the Moonlight'), ('year', '2014-01-01T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q14511869'), ('filmName', 'Magic in the Moonlight'), ('year', '2014-11-13T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q14511869'), ('filmName', 'Magic in the Moonlight'), ('year', '2014-12-04T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q614009'), ('filmName', 'Anything Else'), ('year', '2003-01-01T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q187423'), ('filmName', 'Zelig'), ('year', '1983-01-01T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q187423'), ('filmName', 'Zelig'), ('year', '1983-09-30T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q27703144'), ('filmName', 'Wonder Wheel'), ('year', '2017-12-01T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q27703144'), ('filmName', 'Wonder Wheel'), ('year', '2017-12-07T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q27703144'), ('filmName', 'Wonder Wheel'), ('year', '2018-01-11T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q786585'), ('filmName', 'Sweet and Lowdown'), ('year', '1999-01-01T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q786585'), ('filmName', 'Sweet and Lowdown'), ('year', '2000-03-30T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q1052826'), ('filmName', 'Celebrity'), ('year', '1998-09-07T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q1052826'), ('filmName', 'Celebrity'), ('year', '1999-04-08T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q1218888'), ('filmName', 'Love and Death'), ('year', '1975-01-01T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q181555'), ('filmName', 'Crimes and Misdemeanors'), ('year', '1989-01-01T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q181555'), ('filmName', 'Crimes and Misdemeanors'), ('year', '1990-03-01T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q682002'), ('filmName', 'scoop'), ('year', '2006-01-01T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q682002'), ('filmName', 'scoop'), ('year', '2006-11-16T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q653518'), ('filmName', 'Stardust Memories'), ('year', '1980-01-01T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q653518'), ('filmName', 'Stardust Memories'), ('year', '1981-01-22T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q977372'), ('filmName', 'New York Stories'), ('year', '1989-01-01T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q977372'), ('filmName', 'New York Stories'), ('year', '1989-03-10T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q977372'), ('filmName', 'New York Stories'), ('year', '1989-09-21T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q65552643'), ('filmName', "Rifkin's Festival"), ('year', '2020-01-01T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q750003'), ('filmName', 'Sleeper'), ('year', '1973-12-17T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q750003'), ('filmName', 'Sleeper'), ('year', '1974-04-25T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q610163'), ('filmName', 'Small Time Crooks'), ('year', '2000-01-01T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q610163'), ('filmName', 'Small Time Crooks'), ('year', '2000-11-30T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q910523'), ('filmName', 'Shadows and Fog'), ('year', '1991-01-01T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q910523'), ('filmName', 'Shadows and Fog'), ('year', '1992-02-27T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q1133277'), ('filmName', 'Manhattan Murder Mystery'), ('year', '1993-01-01T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q1133277'), ('filmName', 'Manhattan Murder Mystery'), ('year', '1994-02-03T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q1146315'), ('filmName', 'Take the Money and Run'), ('year', '1969-01-01T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q1354121'), ('filmName', 'Melinda and Melinda'), ('year', '2004-01-01T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q1354121'), ('filmName', 'Melinda and Melinda'), ('year', '2005-03-18T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q1354121'), ('filmName', 'Melinda and Melinda'), ('year', '2005-06-23T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q2907178'), ('filmName', 'Blue Jasmine'), ('year', '2013-07-26T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q2907178'), ('filmName', 'Blue Jasmine'), ('year', '2013-08-29T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q2907178'), ('filmName', 'Blue Jasmine'), ('year', '2013-11-07T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q731310'), ('filmName', 'Manhattan'), ('year', '1979-01-01T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q731310'), ('filmName', 'Manhattan'), ('year', '1979-08-30T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q731310'), ('filmName', 'Manhattan'), ('year', '1979-12-14T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q833530'), ('filmName', "Cassandra's Dream"), ('year', '2007-01-01T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q833530'), ('filmName', "Cassandra's Dream"), ('year', '2008-06-05T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q499697'), ('filmName', 'Everything You Always Wanted to Know About Sex*'), ('year', '1972-01-01T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q912729'), ('filmName', 'The Purple Rose of Cairo'), ('year', '1985-01-01T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q912729'), ('filmName', 'The Purple Rose of Cairo'), ('year', '1985-10-03T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q1770003'), ('filmName', 'September'), ('year', '1987-01-01T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q1770003'), ('filmName', 'September'), ('year', '1988-03-31T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q692208'), ('filmName', 'Whatever Works'), ('year', '2009-01-01T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q692208'), ('filmName', 'Whatever Works'), ('year', '2009-12-03T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q17417520'), ('filmName', 'Irrational Man'), ('year', '2015-05-16T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q29658'), ('filmName', 'To Rome with Love'), ('year', '2012-01-01T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q29658'), ('filmName', 'To Rome with Love'), ('year', '2012-08-30T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q20950014'), ('filmName', 'Café Society'), ('year', '2016-01-01T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q20950014'), ('filmName', 'Café Society'), ('year', '2016-11-10T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q20950014'), ('filmName', 'Café Society'), ('year', '2016-11-17T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q1306629'), ('filmName', "A Midsummer Night's Sex Comedy"), ('year', '1982-01-01T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q1306629'), ('filmName', "A Midsummer Night's Sex Comedy"), ('year', '1982-10-15T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q541185'), ('filmName', 'Another Woman'), ('year', '1988-01-01T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q541185'), ('filmName', 'Another Woman'), ('year', '1989-03-16T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q685109'), ('filmName', 'Radio Days'), ('year', '1987-01-01T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q685109'), ('filmName', 'Radio Days'), ('year', '1987-10-01T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q42307699'), ('filmName', 'A Rainy Day in New York'), ('year', '2019-07-26T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q42307699'), ('filmName', 'A Rainy Day in New York'), ('year', '2019-09-18T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q42307699'), ('filmName', 'A Rainy Day in New York'), ('year', '2019-12-05T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q42307699'), ('filmName', 'A Rainy Day in New York'), ('year', '2019-12-12T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q1334572'), ('filmName', 'Everyone Says I Love You'), ('year', '1996-01-01T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q1334572'), ('filmName', 'Everyone Says I Love You'), ('year', '1996-12-08T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q1334572'), ('filmName', 'Everyone Says I Love You'), ('year', '1997-08-14T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q212123'), ('filmName', 'Vicky Cristina Barcelona'), ('year', '2008-01-01T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q212123'), ('filmName', 'Vicky Cristina Barcelona'), ('year', '2008-12-04T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q233464'), ('filmName', 'Annie Hall'), ('year', '1977-04-20T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q335508'), ('filmName', 'The Curse of the Jade Scorpion'), ('year', '2001-01-01T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q335508'), ('filmName', 'The Curse of the Jade Scorpion'), ('year', '2001-12-06T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q551762'), ('filmName', 'Deconstructing Harry'), ('year', '1997-01-01T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q551762'), ('filmName', 'Deconstructing Harry'), ('year', '1998-05-21T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q582021'), ('filmName', 'Hollywood Ending'), ('year', '2002-01-01T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q845057'), ('filmName', 'Hannah and Her Sisters'), ('year', '1986-02-07T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q845057'), ('filmName', 'Hannah and Her Sisters'), ('year', '1986-10-02T00:00:00Z')]
# 100

# %%
# write your queries
# director (P57)
# film (Q11424)
# Woody Allen (Q25089)
# let's search all the films whom director is Woody Allen
# let's find publication year of each film
queryString = """
SELECT DISTINCT ?film ?filmName (YEAR(?date) AS ?publicationYear)
WHERE {
   # bind something
   # ?film wdt:P57 wd:Q25089;
       wdt:P31 wd:Q11424 ;
       wdt:P577 ?date.
   # get the label
   # ?film sc:name ?filmName.
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('film', 'http://www.wikidata.org/entity/Q3986392'), ('filmName', 'The Concert for New York City'), ('publicationYear', '2001')]
# [('film', 'http://www.wikidata.org/entity/Q206124'), ('filmName', 'Midnight in Paris'), ('publicationYear', '2011')]
# [('film', 'http://www.wikidata.org/entity/Q682262'), ('filmName', 'Alice'), ('publicationYear', '1990')]
# [('film', 'http://www.wikidata.org/entity/Q682262'), ('filmName', 'Alice'), ('publicationYear', '1991')]
# [('film', 'http://www.wikidata.org/entity/Q971865'), ('filmName', "What's Up, Tiger Lily?"), ('publicationYear', '1966')]
# [('film', 'http://www.wikidata.org/entity/Q1004531'), ('filmName', 'Bullets Over Broadway'), ('publicationYear', '1994')]
# [('film', 'http://www.wikidata.org/entity/Q1004531'), ('filmName', 'Bullets Over Broadway'), ('publicationYear', '1995')]
# [('film', 'http://www.wikidata.org/entity/Q1354109'), ('filmName', 'Mighty Aphrodite'), ('publicationYear', '1995')]
# [('film', 'http://www.wikidata.org/entity/Q1354109'), ('filmName', 'Mighty Aphrodite'), ('publicationYear', '1996')]
# [('film', 'http://www.wikidata.org/entity/Q729026'), ('filmName', 'Broadway Danny Rose'), ('publicationYear', '1984')]
# [('film', 'http://www.wikidata.org/entity/Q733677'), ('filmName', 'Match Point'), ('publicationYear', '2005')]
# [('film', 'http://www.wikidata.org/entity/Q740143'), ('filmName', 'Husbands and Wives'), ('publicationYear', '1992')]
# [('film', 'http://www.wikidata.org/entity/Q740143'), ('filmName', 'Husbands and Wives'), ('publicationYear', '1993')]
# [('film', 'http://www.wikidata.org/entity/Q806092'), ('filmName', 'Bananas'), ('publicationYear', '1971')]
# [('film', 'http://www.wikidata.org/entity/Q806092'), ('filmName', 'Bananas'), ('publicationYear', '1974')]
# [('film', 'http://www.wikidata.org/entity/Q1321004'), ('filmName', 'You Will Meet a Tall Dark Stranger'), ('publicationYear', '2010')]
# [('film', 'http://www.wikidata.org/entity/Q14511869'), ('filmName', 'Magic in the Moonlight'), ('publicationYear', '2014')]
# [('film', 'http://www.wikidata.org/entity/Q614009'), ('filmName', 'Anything Else'), ('publicationYear', '2003')]
# [('film', 'http://www.wikidata.org/entity/Q187423'), ('filmName', 'Zelig'), ('publicationYear', '1983')]
# [('film', 'http://www.wikidata.org/entity/Q27703144'), ('filmName', 'Wonder Wheel'), ('publicationYear', '2017')]
# [('film', 'http://www.wikidata.org/entity/Q27703144'), ('filmName', 'Wonder Wheel'), ('publicationYear', '2018')]
# [('film', 'http://www.wikidata.org/entity/Q786585'), ('filmName', 'Sweet and Lowdown'), ('publicationYear', '1999')]
# [('film', 'http://www.wikidata.org/entity/Q786585'), ('filmName', 'Sweet and Lowdown'), ('publicationYear', '2000')]
# [('film', 'http://www.wikidata.org/entity/Q1052826'), ('filmName', 'Celebrity'), ('publicationYear', '1998')]
# [('film', 'http://www.wikidata.org/entity/Q1052826'), ('filmName', 'Celebrity'), ('publicationYear', '1999')]
# [('film', 'http://www.wikidata.org/entity/Q1218888'), ('filmName', 'Love and Death'), ('publicationYear', '1975')]
# [('film', 'http://www.wikidata.org/entity/Q181555'), ('filmName', 'Crimes and Misdemeanors'), ('publicationYear', '1989')]
# [('film', 'http://www.wikidata.org/entity/Q181555'), ('filmName', 'Crimes and Misdemeanors'), ('publicationYear', '1990')]
# [('film', 'http://www.wikidata.org/entity/Q682002'), ('filmName', 'scoop'), ('publicationYear', '2006')]
# [('film', 'http://www.wikidata.org/entity/Q653518'), ('filmName', 'Stardust Memories'), ('publicationYear', '1980')]
# [('film', 'http://www.wikidata.org/entity/Q653518'), ('filmName', 'Stardust Memories'), ('publicationYear', '1981')]
# [('film', 'http://www.wikidata.org/entity/Q977372'), ('filmName', 'New York Stories'), ('publicationYear', '1989')]
# [('film', 'http://www.wikidata.org/entity/Q65552643'), ('filmName', "Rifkin's Festival"), ('publicationYear', '2020')]
# [('film', 'http://www.wikidata.org/entity/Q750003'), ('filmName', 'Sleeper'), ('publicationYear', '1973')]
# [('film', 'http://www.wikidata.org/entity/Q750003'), ('filmName', 'Sleeper'), ('publicationYear', '1974')]
# [('film', 'http://www.wikidata.org/entity/Q610163'), ('filmName', 'Small Time Crooks'), ('publicationYear', '2000')]
# [('film', 'http://www.wikidata.org/entity/Q910523'), ('filmName', 'Shadows and Fog'), ('publicationYear', '1991')]
# [('film', 'http://www.wikidata.org/entity/Q910523'), ('filmName', 'Shadows and Fog'), ('publicationYear', '1992')]
# [('film', 'http://www.wikidata.org/entity/Q1133277'), ('filmName', 'Manhattan Murder Mystery'), ('publicationYear', '1993')]
# [('film', 'http://www.wikidata.org/entity/Q1133277'), ('filmName', 'Manhattan Murder Mystery'), ('publicationYear', '1994')]
# [('film', 'http://www.wikidata.org/entity/Q1146315'), ('filmName', 'Take the Money and Run'), ('publicationYear', '1969')]
# [('film', 'http://www.wikidata.org/entity/Q1354121'), ('filmName', 'Melinda and Melinda'), ('publicationYear', '2004')]
# [('film', 'http://www.wikidata.org/entity/Q1354121'), ('filmName', 'Melinda and Melinda'), ('publicationYear', '2005')]
# [('film', 'http://www.wikidata.org/entity/Q2907178'), ('filmName', 'Blue Jasmine'), ('publicationYear', '2013')]
# [('film', 'http://www.wikidata.org/entity/Q731310'), ('filmName', 'Manhattan'), ('publicationYear', '1979')]
# [('film', 'http://www.wikidata.org/entity/Q833530'), ('filmName', "Cassandra's Dream"), ('publicationYear', '2007')]
# [('film', 'http://www.wikidata.org/entity/Q833530'), ('filmName', "Cassandra's Dream"), ('publicationYear', '2008')]
# [('film', 'http://www.wikidata.org/entity/Q499697'), ('filmName', 'Everything You Always Wanted to Know About Sex*'), ('publicationYear', '1972')]
# [('film', 'http://www.wikidata.org/entity/Q912729'), ('filmName', 'The Purple Rose of Cairo'), ('publicationYear', '1985')]
# [('film', 'http://www.wikidata.org/entity/Q1770003'), ('filmName', 'September'), ('publicationYear', '1987')]
# [('film', 'http://www.wikidata.org/entity/Q1770003'), ('filmName', 'September'), ('publicationYear', '1988')]
# [('film', 'http://www.wikidata.org/entity/Q692208'), ('filmName', 'Whatever Works'), ('publicationYear', '2009')]
# [('film', 'http://www.wikidata.org/entity/Q17417520'), ('filmName', 'Irrational Man'), ('publicationYear', '2015')]
# [('film', 'http://www.wikidata.org/entity/Q29658'), ('filmName', 'To Rome with Love'), ('publicationYear', '2012')]
# [('film', 'http://www.wikidata.org/entity/Q20950014'), ('filmName', 'Café Society'), ('publicationYear', '2016')]
# [('film', 'http://www.wikidata.org/entity/Q1306629'), ('filmName', "A Midsummer Night's Sex Comedy"), ('publicationYear', '1982')]
# [('film', 'http://www.wikidata.org/entity/Q541185'), ('filmName', 'Another Woman'), ('publicationYear', '1988')]
# [('film', 'http://www.wikidata.org/entity/Q541185'), ('filmName', 'Another Woman'), ('publicationYear', '1989')]
# [('film', 'http://www.wikidata.org/entity/Q685109'), ('filmName', 'Radio Days'), ('publicationYear', '1987')]
# [('film', 'http://www.wikidata.org/entity/Q42307699'), ('filmName', 'A Rainy Day in New York'), ('publicationYear', '2019')]
# [('film', 'http://www.wikidata.org/entity/Q1334572'), ('filmName', 'Everyone Says I Love You'), ('publicationYear', '1996')]
# [('film', 'http://www.wikidata.org/entity/Q1334572'), ('filmName', 'Everyone Says I Love You'), ('publicationYear', '1997')]
# [('film', 'http://www.wikidata.org/entity/Q212123'), ('filmName', 'Vicky Cristina Barcelona'), ('publicationYear', '2008')]
# [('film', 'http://www.wikidata.org/entity/Q233464'), ('filmName', 'Annie Hall'), ('publicationYear', '1977')]
# [('film', 'http://www.wikidata.org/entity/Q335508'), ('filmName', 'The Curse of the Jade Scorpion'), ('publicationYear', '2001')]
# [('film', 'http://www.wikidata.org/entity/Q551762'), ('filmName', 'Deconstructing Harry'), ('publicationYear', '1997')]
# [('film', 'http://www.wikidata.org/entity/Q551762'), ('filmName', 'Deconstructing Harry'), ('publicationYear', '1998')]
# [('film', 'http://www.wikidata.org/entity/Q582021'), ('filmName', 'Hollywood Ending'), ('publicationYear', '2002')]
# [('film', 'http://www.wikidata.org/entity/Q845057'), ('filmName', 'Hannah and Her Sisters'), ('publicationYear', '1986')]
# [('film', 'http://www.wikidata.org/entity/Q961403'), ('filmName', 'Interiors'), ('publicationYear', '1978')]
# 70

# %%
# write your queries
# director (P57)
# film (Q11424)
# publication date (P577)
# Woody Allen (Q25089)
# let's search all the films whom director is Woody Allen
# let's find publication year of each film
# let's try to find with first date of publication because some are showing with double
queryString = """
SELECT DISTINCT ?film ?filmName (YEAR(?date) AS ?publicationYear)
WHERE {
   # bind something
   # ?film wdt:P57 wd:Q25089;
       wdt:P31 wd:Q11424 ;
       wdt:P577 ?date.
   
   filter NOT EXISTS{
       # ?film wdt:P577 ?secondDate .
       filter(?secondDate < ?date) .
   }
   # get the label
   # ?film sc:name ?filmName.
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('film', 'http://www.wikidata.org/entity/Q3986392'), ('filmName', 'The Concert for New York City'), ('publicationYear', '2001')]
# [('film', 'http://www.wikidata.org/entity/Q206124'), ('filmName', 'Midnight in Paris'), ('publicationYear', '2011')]
# [('film', 'http://www.wikidata.org/entity/Q682262'), ('filmName', 'Alice'), ('publicationYear', '1990')]
# [('film', 'http://www.wikidata.org/entity/Q971865'), ('filmName', "What's Up, Tiger Lily?"), ('publicationYear', '1966')]
# [('film', 'http://www.wikidata.org/entity/Q1004531'), ('filmName', 'Bullets Over Broadway'), ('publicationYear', '1994')]
# [('film', 'http://www.wikidata.org/entity/Q1354109'), ('filmName', 'Mighty Aphrodite'), ('publicationYear', '1995')]
# [('film', 'http://www.wikidata.org/entity/Q729026'), ('filmName', 'Broadway Danny Rose'), ('publicationYear', '1984')]
# [('film', 'http://www.wikidata.org/entity/Q733677'), ('filmName', 'Match Point'), ('publicationYear', '2005')]
# [('film', 'http://www.wikidata.org/entity/Q740143'), ('filmName', 'Husbands and Wives'), ('publicationYear', '1992')]
# [('film', 'http://www.wikidata.org/entity/Q806092'), ('filmName', 'Bananas'), ('publicationYear', '1971')]
# [('film', 'http://www.wikidata.org/entity/Q1321004'), ('filmName', 'You Will Meet a Tall Dark Stranger'), ('publicationYear', '2010')]
# [('film', 'http://www.wikidata.org/entity/Q14511869'), ('filmName', 'Magic in the Moonlight'), ('publicationYear', '2014')]
# [('film', 'http://www.wikidata.org/entity/Q614009'), ('filmName', 'Anything Else'), ('publicationYear', '2003')]
# [('film', 'http://www.wikidata.org/entity/Q187423'), ('filmName', 'Zelig'), ('publicationYear', '1983')]
# [('film', 'http://www.wikidata.org/entity/Q27703144'), ('filmName', 'Wonder Wheel'), ('publicationYear', '2017')]
# [('film', 'http://www.wikidata.org/entity/Q786585'), ('filmName', 'Sweet and Lowdown'), ('publicationYear', '1999')]
# [('film', 'http://www.wikidata.org/entity/Q1052826'), ('filmName', 'Celebrity'), ('publicationYear', '1998')]
# [('film', 'http://www.wikidata.org/entity/Q1218888'), ('filmName', 'Love and Death'), ('publicationYear', '1975')]
# [('film', 'http://www.wikidata.org/entity/Q181555'), ('filmName', 'Crimes and Misdemeanors'), ('publicationYear', '1989')]
# [('film', 'http://www.wikidata.org/entity/Q682002'), ('filmName', 'scoop'), ('publicationYear', '2006')]
# [('film', 'http://www.wikidata.org/entity/Q653518'), ('filmName', 'Stardust Memories'), ('publicationYear', '1980')]
# [('film', 'http://www.wikidata.org/entity/Q977372'), ('filmName', 'New York Stories'), ('publicationYear', '1989')]
# [('film', 'http://www.wikidata.org/entity/Q65552643'), ('filmName', "Rifkin's Festival"), ('publicationYear', '2020')]
# [('film', 'http://www.wikidata.org/entity/Q750003'), ('filmName', 'Sleeper'), ('publicationYear', '1973')]
# [('film', 'http://www.wikidata.org/entity/Q610163'), ('filmName', 'Small Time Crooks'), ('publicationYear', '2000')]
# [('film', 'http://www.wikidata.org/entity/Q910523'), ('filmName', 'Shadows and Fog'), ('publicationYear', '1991')]
# [('film', 'http://www.wikidata.org/entity/Q1133277'), ('filmName', 'Manhattan Murder Mystery'), ('publicationYear', '1993')]
# [('film', 'http://www.wikidata.org/entity/Q1146315'), ('filmName', 'Take the Money and Run'), ('publicationYear', '1969')]
# [('film', 'http://www.wikidata.org/entity/Q1354121'), ('filmName', 'Melinda and Melinda'), ('publicationYear', '2004')]
# [('film', 'http://www.wikidata.org/entity/Q2907178'), ('filmName', 'Blue Jasmine'), ('publicationYear', '2013')]
# [('film', 'http://www.wikidata.org/entity/Q731310'), ('filmName', 'Manhattan'), ('publicationYear', '1979')]
# [('film', 'http://www.wikidata.org/entity/Q833530'), ('filmName', "Cassandra's Dream"), ('publicationYear', '2007')]
# [('film', 'http://www.wikidata.org/entity/Q499697'), ('filmName', 'Everything You Always Wanted to Know About Sex*'), ('publicationYear', '1972')]
# [('film', 'http://www.wikidata.org/entity/Q912729'), ('filmName', 'The Purple Rose of Cairo'), ('publicationYear', '1985')]
# [('film', 'http://www.wikidata.org/entity/Q1770003'), ('filmName', 'September'), ('publicationYear', '1987')]
# [('film', 'http://www.wikidata.org/entity/Q692208'), ('filmName', 'Whatever Works'), ('publicationYear', '2009')]
# [('film', 'http://www.wikidata.org/entity/Q17417520'), ('filmName', 'Irrational Man'), ('publicationYear', '2015')]
# [('film', 'http://www.wikidata.org/entity/Q29658'), ('filmName', 'To Rome with Love'), ('publicationYear', '2012')]
# [('film', 'http://www.wikidata.org/entity/Q20950014'), ('filmName', 'Café Society'), ('publicationYear', '2016')]
# [('film', 'http://www.wikidata.org/entity/Q1306629'), ('filmName', "A Midsummer Night's Sex Comedy"), ('publicationYear', '1982')]
# [('film', 'http://www.wikidata.org/entity/Q541185'), ('filmName', 'Another Woman'), ('publicationYear', '1988')]
# [('film', 'http://www.wikidata.org/entity/Q685109'), ('filmName', 'Radio Days'), ('publicationYear', '1987')]
# [('film', 'http://www.wikidata.org/entity/Q42307699'), ('filmName', 'A Rainy Day in New York'), ('publicationYear', '2019')]
# [('film', 'http://www.wikidata.org/entity/Q1334572'), ('filmName', 'Everyone Says I Love You'), ('publicationYear', '1996')]
# [('film', 'http://www.wikidata.org/entity/Q212123'), ('filmName', 'Vicky Cristina Barcelona'), ('publicationYear', '2008')]
# [('film', 'http://www.wikidata.org/entity/Q233464'), ('filmName', 'Annie Hall'), ('publicationYear', '1977')]
# [('film', 'http://www.wikidata.org/entity/Q335508'), ('filmName', 'The Curse of the Jade Scorpion'), ('publicationYear', '2001')]
# [('film', 'http://www.wikidata.org/entity/Q551762'), ('filmName', 'Deconstructing Harry'), ('publicationYear', '1997')]
# [('film', 'http://www.wikidata.org/entity/Q582021'), ('filmName', 'Hollywood Ending'), ('publicationYear', '2002')]
# [('film', 'http://www.wikidata.org/entity/Q845057'), ('filmName', 'Hannah and Her Sisters'), ('publicationYear', '1986')]
# [('film', 'http://www.wikidata.org/entity/Q961403'), ('filmName', 'Interiors'), ('publicationYear', '1978')]
# 51

# %%
# write your queries
# director (P57)
# film (Q11424)
# publication date (P577)
# Woody Allen (Q25089)
# let's search all the films whom director is Woody Allen
# let's find publication year of each film
# let's try to find with first date of publication because some are showing with double publication dates
queryString = """
SELECT DISTINCT ?film ?filmName (YEAR(?date) AS ?publicationYear) (COUNT(?film) AS ?numFilms)
WHERE {
   # bind something
   # ?film wdt:P57 wd:Q25089;
       wdt:P31 wd:Q11424 ;
       wdt:P577 ?date.
   
   filter NOT EXISTS{
       # ?film wdt:P577 ?secondDate .
       filter(?secondDate < ?date) .
   }
   # get the label
   # ?film sc:name ?filmName.
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('film', 'http://www.wikidata.org/entity/Q206124'), ('filmName', 'Midnight in Paris'), ('publicationYear', '2011'), ('numFilms', '1')]
# [('film', 'http://www.wikidata.org/entity/Q806092'), ('filmName', 'Bananas'), ('publicationYear', '1971'), ('numFilms', '1')]
# [('film', 'http://www.wikidata.org/entity/Q187423'), ('filmName', 'Zelig'), ('publicationYear', '1983'), ('numFilms', '1')]
# [('film', 'http://www.wikidata.org/entity/Q3986392'), ('filmName', 'The Concert for New York City'), ('publicationYear', '2001'), ('numFilms', '1')]
# [('film', 'http://www.wikidata.org/entity/Q682262'), ('filmName', 'Alice'), ('publicationYear', '1990'), ('numFilms', '1')]
# [('film', 'http://www.wikidata.org/entity/Q614009'), ('filmName', 'Anything Else'), ('publicationYear', '2003'), ('numFilms', '1')]
# [('film', 'http://www.wikidata.org/entity/Q910523'), ('filmName', 'Shadows and Fog'), ('publicationYear', '1991'), ('numFilms', '1')]
# [('film', 'http://www.wikidata.org/entity/Q1133277'), ('filmName', 'Manhattan Murder Mystery'), ('publicationYear', '1993'), ('numFilms', '1')]
# [('film', 'http://www.wikidata.org/entity/Q1770003'), ('filmName', 'September'), ('publicationYear', '1987'), ('numFilms', '1')]
# [('film', 'http://www.wikidata.org/entity/Q1306629'), ('filmName', "A Midsummer Night's Sex Comedy"), ('publicationYear', '1982'), ('numFilms', '1')]
# [('film', 'http://www.wikidata.org/entity/Q1334572'), ('filmName', 'Everyone Says I Love You'), ('publicationYear', '1996'), ('numFilms', '1')]
# [('film', 'http://www.wikidata.org/entity/Q233464'), ('filmName', 'Annie Hall'), ('publicationYear', '1977'), ('numFilms', '1')]
# [('film', 'http://www.wikidata.org/entity/Q551762'), ('filmName', 'Deconstructing Harry'), ('publicationYear', '1997'), ('numFilms', '1')]
# [('film', 'http://www.wikidata.org/entity/Q1354109'), ('filmName', 'Mighty Aphrodite'), ('publicationYear', '1995'), ('numFilms', '1')]
# [('film', 'http://www.wikidata.org/entity/Q729026'), ('filmName', 'Broadway Danny Rose'), ('publicationYear', '1984'), ('numFilms', '1')]
# [('film', 'http://www.wikidata.org/entity/Q582021'), ('filmName', 'Hollywood Ending'), ('publicationYear', '2002'), ('numFilms', '1')]
# [('film', 'http://www.wikidata.org/entity/Q65552643'), ('filmName', "Rifkin's Festival"), ('publicationYear', '2020'), ('numFilms', '1')]
# [('film', 'http://www.wikidata.org/entity/Q27703144'), ('filmName', 'Wonder Wheel'), ('publicationYear', '2017'), ('numFilms', '1')]
# [('film', 'http://www.wikidata.org/entity/Q682002'), ('filmName', 'scoop'), ('publicationYear', '2006'), ('numFilms', '1')]
# [('film', 'http://www.wikidata.org/entity/Q20950014'), ('filmName', 'Café Society'), ('publicationYear', '2016'), ('numFilms', '1')]
# [('film', 'http://www.wikidata.org/entity/Q845057'), ('filmName', 'Hannah and Her Sisters'), ('publicationYear', '1986'), ('numFilms', '1')]
# [('film', 'http://www.wikidata.org/entity/Q733677'), ('filmName', 'Match Point'), ('publicationYear', '2005'), ('numFilms', '1')]
# [('film', 'http://www.wikidata.org/entity/Q1218888'), ('filmName', 'Love and Death'), ('publicationYear', '1975'), ('numFilms', '1')]
# [('film', 'http://www.wikidata.org/entity/Q731310'), ('filmName', 'Manhattan'), ('publicationYear', '1979'), ('numFilms', '1')]
# [('film', 'http://www.wikidata.org/entity/Q335508'), ('filmName', 'The Curse of the Jade Scorpion'), ('publicationYear', '2001'), ('numFilms', '1')]
# [('film', 'http://www.wikidata.org/entity/Q181555'), ('filmName', 'Crimes and Misdemeanors'), ('publicationYear', '1989'), ('numFilms', '1')]
# [('film', 'http://www.wikidata.org/entity/Q977372'), ('filmName', 'New York Stories'), ('publicationYear', '1989'), ('numFilms', '1')]
# [('film', 'http://www.wikidata.org/entity/Q17417520'), ('filmName', 'Irrational Man'), ('publicationYear', '2015'), ('numFilms', '1')]
# [('film', 'http://www.wikidata.org/entity/Q685109'), ('filmName', 'Radio Days'), ('publicationYear', '1987'), ('numFilms', '1')]
# [('film', 'http://www.wikidata.org/entity/Q750003'), ('filmName', 'Sleeper'), ('publicationYear', '1973'), ('numFilms', '1')]
# [('film', 'http://www.wikidata.org/entity/Q1146315'), ('filmName', 'Take the Money and Run'), ('publicationYear', '1969'), ('numFilms', '1')]
# [('film', 'http://www.wikidata.org/entity/Q2907178'), ('filmName', 'Blue Jasmine'), ('publicationYear', '2013'), ('numFilms', '1')]
# [('film', 'http://www.wikidata.org/entity/Q833530'), ('filmName', "Cassandra's Dream"), ('publicationYear', '2007'), ('numFilms', '1')]
# [('film', 'http://www.wikidata.org/entity/Q29658'), ('filmName', 'To Rome with Love'), ('publicationYear', '2012'), ('numFilms', '1')]
# [('film', 'http://www.wikidata.org/entity/Q971865'), ('filmName', "What's Up, Tiger Lily?"), ('publicationYear', '1966'), ('numFilms', '1')]
# [('film', 'http://www.wikidata.org/entity/Q14511869'), ('filmName', 'Magic in the Moonlight'), ('publicationYear', '2014'), ('numFilms', '1')]
# [('film', 'http://www.wikidata.org/entity/Q1052826'), ('filmName', 'Celebrity'), ('publicationYear', '1998'), ('numFilms', '1')]
# [('film', 'http://www.wikidata.org/entity/Q499697'), ('filmName', 'Everything You Always Wanted to Know About Sex*'), ('publicationYear', '1972'), ('numFilms', '1')]
# [('film', 'http://www.wikidata.org/entity/Q692208'), ('filmName', 'Whatever Works'), ('publicationYear', '2009'), ('numFilms', '1')]
# [('film', 'http://www.wikidata.org/entity/Q541185'), ('filmName', 'Another Woman'), ('publicationYear', '1988'), ('numFilms', '1')]
# [('film', 'http://www.wikidata.org/entity/Q42307699'), ('filmName', 'A Rainy Day in New York'), ('publicationYear', '2019'), ('numFilms', '1')]
# [('film', 'http://www.wikidata.org/entity/Q212123'), ('filmName', 'Vicky Cristina Barcelona'), ('publicationYear', '2008'), ('numFilms', '1')]
# [('film', 'http://www.wikidata.org/entity/Q740143'), ('filmName', 'Husbands and Wives'), ('publicationYear', '1992'), ('numFilms', '1')]
# [('film', 'http://www.wikidata.org/entity/Q786585'), ('filmName', 'Sweet and Lowdown'), ('publicationYear', '1999'), ('numFilms', '1')]
# [('film', 'http://www.wikidata.org/entity/Q912729'), ('filmName', 'The Purple Rose of Cairo'), ('publicationYear', '1985'), ('numFilms', '1')]
# [('film', 'http://www.wikidata.org/entity/Q961403'), ('filmName', 'Interiors'), ('publicationYear', '1978'), ('numFilms', '1')]
# [('film', 'http://www.wikidata.org/entity/Q1004531'), ('filmName', 'Bullets Over Broadway'), ('publicationYear', '1994'), ('numFilms', '1')]
# [('film', 'http://www.wikidata.org/entity/Q1321004'), ('filmName', 'You Will Meet a Tall Dark Stranger'), ('publicationYear', '2010'), ('numFilms', '1')]
# [('film', 'http://www.wikidata.org/entity/Q653518'), ('filmName', 'Stardust Memories'), ('publicationYear', '1980'), ('numFilms', '1')]
# [('film', 'http://www.wikidata.org/entity/Q610163'), ('filmName', 'Small Time Crooks'), ('publicationYear', '2000'), ('numFilms', '1')]
# [('film', 'http://www.wikidata.org/entity/Q1354121'), ('filmName', 'Melinda and Melinda'), ('publicationYear', '2004'), ('numFilms', '1')]
# 51

# %%
# write your queries
# director (P57)
# film (Q11424)
# publication date (P577)
# Woody Allen (Q25089)
# Quentin Tarantino (Q3772)
# let's search all the films whom director is Woody Allen and count it
# let's find publication year of each film
# let's try to find with first date of publication because some are showing with double publication dates
queryString = """
SELECT DISTINCT (YEAR(?date) AS ?publicationYear) (COUNT(?film) AS ?numFilms)
WHERE {
   # bind something
   # ?film wdt:P57 wd:Q25089;
       wdt:P31 wd:Q11424 ;
       wdt:P577 ?date.
   
   filter NOT EXISTS{
       # ?film wdt:P577 ?secondDate .
       filter(?secondDate < ?date) .
   }
   # get the label
  # ?film sc:name ?filmName.
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('publicationYear', '2000'), ('numFilms', '1')]
# [('publicationYear', '2004'), ('numFilms', '1')]
# [('publicationYear', '2007'), ('numFilms', '1')]
# [('publicationYear', '1985'), ('numFilms', '1')]
# [('publicationYear', '1978'), ('numFilms', '1')]
# [('publicationYear', '1966'), ('numFilms', '1')]
# [('publicationYear', '1999'), ('numFilms', '1')]
# [('publicationYear', '1998'), ('numFilms', '1')]
# [('publicationYear', '1996'), ('numFilms', '1')]
# [('publicationYear', '1971'), ('numFilms', '1')]
# [('publicationYear', '2006'), ('numFilms', '1')]
# [('publicationYear', '1987'), ('numFilms', '2')]
# [('publicationYear', '1990'), ('numFilms', '1')]
# [('publicationYear', '2010'), ('numFilms', '1')]
# [('publicationYear', '2017'), ('numFilms', '1')]
# [('publicationYear', '1973'), ('numFilms', '1')]
# [('publicationYear', '1991'), ('numFilms', '1')]
# [('publicationYear', '2015'), ('numFilms', '1')]
# [('publicationYear', '2002'), ('numFilms', '1')]
# [('publicationYear', '1983'), ('numFilms', '1')]
# [('publicationYear', '1989'), ('numFilms', '2')]
# [('publicationYear', '1988'), ('numFilms', '1')]
# [('publicationYear', '2001'), ('numFilms', '2')]
# [('publicationYear', '1994'), ('numFilms', '1')]
# [('publicationYear', '2005'), ('numFilms', '1')]
# [('publicationYear', '1992'), ('numFilms', '1')]
# [('publicationYear', '1972'), ('numFilms', '1')]
# [('publicationYear', '2009'), ('numFilms', '1')]
# [('publicationYear', '1982'), ('numFilms', '1')]
# [('publicationYear', '2008'), ('numFilms', '1')]
# [('publicationYear', '2011'), ('numFilms', '1')]
# [('publicationYear', '1980'), ('numFilms', '1')]
# [('publicationYear', '1993'), ('numFilms', '1')]
# [('publicationYear', '1969'), ('numFilms', '1')]
# [('publicationYear', '2019'), ('numFilms', '1')]
# [('publicationYear', '1995'), ('numFilms', '1')]
# [('publicationYear', '2014'), ('numFilms', '1')]
# [('publicationYear', '2016'), ('numFilms', '1')]
# [('publicationYear', '1997'), ('numFilms', '1')]
# [('publicationYear', '2020'), ('numFilms', '1')]
# [('publicationYear', '1977'), ('numFilms', '1')]
# [('publicationYear', '1986'), ('numFilms', '1')]
# [('publicationYear', '2003'), ('numFilms', '1')]
# [('publicationYear', '1979'), ('numFilms', '1')]
# [('publicationYear', '1984'), ('numFilms', '1')]
# [('publicationYear', '1975'), ('numFilms', '1')]
# [('publicationYear', '2013'), ('numFilms', '1')]
# [('publicationYear', '2012'), ('numFilms', '1')]
# 48

# %%
# write your queries
# director (P57)
# film (Q11424)
# publication date (P577)
# Woody Allen (Q25089)
# Quentin Tarantino (Q3772)
# let's search all the films whom director is Woody Allen
# let's find publication year of each film
# let's try to find with first date of publication because some are showing with double
queryString = """
SELECT DISTINCT ?dir ?dirName (YEAR(?date) AS ?publicationYear) (COUNT(?film) AS ?numFilms)
WHERE {
   # bind something
   # ?film wdt:P57 ?dir;
       wdt:P31 wd:Q11424 ;
       wdt:P577 ?date.
   # ?dir sc:name ?dirName
   filter NOT EXISTS{
       # ?film wdt:P577 ?secondDate .
       filter(?secondDate < ?date) .
   }
   # get the label
  # ?film sc:name ?filmName.
}
LIMIT 50
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('dir', 'http://www.wikidata.org/entity/Q3318647'), ('dirName', 'Mohamed Khan'), ('publicationYear', '1984'), ('numFilms', '1')]
# [('dir', 'http://www.wikidata.org/entity/Q744326'), ('dirName', 'Victor Saville'), ('publicationYear', '1933'), ('numFilms', '3')]
# [('dir', 'http://www.wikidata.org/entity/Q543563'), ('dirName', 'Phillip Noyce'), ('publicationYear', '2014'), ('numFilms', '1')]
# [('dir', 'http://www.wikidata.org/entity/Q15930508'), ('dirName', 'Henry Chan'), ('publicationYear', '2013'), ('numFilms', '1')]
# [('dir', 'http://www.wikidata.org/entity/Q750983'), ('dirName', 'Riccardo Freda'), ('publicationYear', '1951'), ('numFilms', '3')]
# [('dir', 'http://www.wikidata.org/entity/Q3101789'), ('dirName', 'George Nicholls, Jr.'), ('publicationYear', '1938'), ('numFilms', '1')]
# [('dir', 'http://www.wikidata.org/entity/Q11985796'), ('dirName', 'F. Šestka'), ('publicationYear', '1935'), ('numFilms', '1')]
# [('dir', 'http://www.wikidata.org/entity/Q6235036'), ('dirName', 'Poul Welander'), ('publicationYear', '1912'), ('numFilms', '7')]
# [('dir', 'http://www.wikidata.org/entity/Q39072589'), ('dirName', 'Anne-Sophie Birot'), ('publicationYear', '2000'), ('numFilms', '1')]
# [('dir', 'http://www.wikidata.org/entity/Q55221'), ('dirName', 'Alexander Korda'), ('publicationYear', '1932'), ('numFilms', '3')]
# [('dir', 'http://www.wikidata.org/entity/Q47027678'), ('dirName', 'Dhavala Satyam'), ('publicationYear', '2010'), ('numFilms', '1')]
# [('dir', 'http://www.wikidata.org/entity/Q18128514'), ('dirName', 'Babu Narayanan'), ('publicationYear', '1990'), ('numFilms', '1')]
# [('dir', 'http://www.wikidata.org/entity/Q12843183'), ('dirName', 'Nazim Abbas'), ('publicationYear', '2001'), ('numFilms', '2')]
# [('dir', 'http://www.wikidata.org/entity/Q11120593'), ('dirName', 'Milan Jelić'), ('publicationYear', '1990'), ('numFilms', '1')]
# [('dir', 'http://www.wikidata.org/entity/Q708899'), ('dirName', 'Gregg Araki'), ('publicationYear', '1997'), ('numFilms', '1')]
# [('dir', 'http://www.wikidata.org/entity/Q3379960'), ('dirName', 'Philippe Grandrieux'), ('publicationYear', '2015'), ('numFilms', '1')]
# [('dir', 'http://www.wikidata.org/entity/Q7645752'), ('dirName', 'Suresh Krissna'), ('publicationYear', '2003'), ('numFilms', '1')]
# [('dir', 'http://www.wikidata.org/entity/Q12275286'), ('dirName', 'Vili Tzankov'), ('publicationYear', '1973'), ('numFilms', '1')]
# [('dir', 'http://www.wikidata.org/entity/Q1331254'), ('dirName', 'Ulrike Grote'), ('publicationYear', '2008'), ('numFilms', '1')]
# [('dir', 'http://www.wikidata.org/entity/Q54104869'), ('dirName', 'Bojan Vuletić'), ('publicationYear', '2017'), ('numFilms', '1')]
# [('dir', 'http://www.wikidata.org/entity/Q3167840'), ('dirName', 'Jean-Marie Teno'), ('publicationYear', '1999'), ('numFilms', '1')]
# [('dir', 'http://www.wikidata.org/entity/Q381876'), ('dirName', 'Jan Troell'), ('publicationYear', '1988'), ('numFilms', '1')]
# [('dir', 'http://www.wikidata.org/entity/Q543630'), ('dirName', 'Sidney Olcott'), ('publicationYear', '1927'), ('numFilms', '1')]
# [('dir', 'http://www.wikidata.org/entity/Q98223754'), ('dirName', 'Kristen Bruun Petersen'), ('publicationYear', '1987'), ('numFilms', '1')]
# [('dir', 'http://www.wikidata.org/entity/Q78667'), ('dirName', 'Christian Berger'), ('publicationYear', '1989'), ('numFilms', '1')]
# [('dir', 'http://www.wikidata.org/entity/Q3339525'), ('dirName', 'Niazi Moustapha'), ('publicationYear', '1959'), ('numFilms', '1')]
# [('dir', 'http://www.wikidata.org/entity/Q5941322'), ('dirName', 'Humphrey Burton'), ('publicationYear', '1998'), ('numFilms', '1')]
# [('dir', 'http://www.wikidata.org/entity/Q4772475'), ('dirName', 'Anthony Fabian'), ('publicationYear', '2022'), ('numFilms', '1')]
# [('dir', 'http://www.wikidata.org/entity/Q3313145'), ('dirName', 'Mikael Buch'), ('publicationYear', '2011'), ('numFilms', '1')]
# [('dir', 'http://www.wikidata.org/entity/Q4889677'), ('dirName', 'Bennett Cohen'), ('publicationYear', '1928'), ('numFilms', '1')]
# [('dir', 'http://www.wikidata.org/entity/Q2273051'), ('dirName', 'Sergio Bergonzelli'), ('publicationYear', '1971'), ('numFilms', '3')]
# [('dir', 'http://www.wikidata.org/entity/Q495980'), ('dirName', 'Bong Joon-ho'), ('publicationYear', '2019'), ('numFilms', '1')]
# [('dir', 'http://www.wikidata.org/entity/Q6813455'), ('dirName', 'Melody Gilbert'), ('publicationYear', '2005'), ('numFilms', '1')]
# [('dir', 'http://www.wikidata.org/entity/Q710654'), ('dirName', 'Gérard Blain'), ('publicationYear', '1976'), ('numFilms', '1')]
# [('dir', 'http://www.wikidata.org/entity/Q3173995'), ('dirName', 'Jean Pierre Lefebvre'), ('publicationYear', '1969'), ('numFilms', '2')]
# [('dir', 'http://www.wikidata.org/entity/Q16082830'), ('dirName', 'Bae Chang-ho'), ('publicationYear', '1982'), ('numFilms', '1')]
# [('dir', 'http://www.wikidata.org/entity/Q1688645'), ('dirName', 'Yevgeni Bauer'), ('publicationYear', '1914'), ('numFilms', '4')]
# [('dir', 'http://www.wikidata.org/entity/Q4352842'), ('dirName', 'Andrei Blaier'), ('publicationYear', '1969'), ('numFilms', '1')]
# [('dir', 'http://www.wikidata.org/entity/Q31092931'), ('dirName', 'Jenő Hódi'), ('publicationYear', '1993'), ('numFilms', '1')]
# [('dir', 'http://www.wikidata.org/entity/Q3788813'), ('dirName', 'William Haggar'), ('publicationYear', '1903'), ('numFilms', '1')]
# [('dir', 'http://www.wikidata.org/entity/Q20393371'), ('dirName', 'Hassan El-Seify'), ('publicationYear', '1990'), ('numFilms', '1')]
# [('dir', 'http://www.wikidata.org/entity/Q3425963'), ('dirName', 'René Cardona'), ('publicationYear', '1962'), ('numFilms', '1')]
# [('dir', 'http://www.wikidata.org/entity/Q957202'), ('dirName', 'Sidney Lanfield'), ('publicationYear', '1938'), ('numFilms', '1')]
# [('dir', 'http://www.wikidata.org/entity/Q26208'), ('dirName', 'Carlo Lizzani'), ('publicationYear', '2005'), ('numFilms', '1')]
# [('dir', 'http://www.wikidata.org/entity/Q4686000'), ('dirName', 'Adurthi Subba Rao'), ('publicationYear', '1973'), ('numFilms', '2')]
# [('dir', 'http://www.wikidata.org/entity/Q1138078'), ('dirName', 'Yukihiko Tsutsumi'), ('publicationYear', '2003'), ('numFilms', '3')]
# [('dir', 'http://www.wikidata.org/entity/Q3350742'), ('dirName', 'Olivier Abbou'), ('publicationYear', '2011'), ('numFilms', '1')]
# [('dir', 'http://www.wikidata.org/entity/Q15065263'), ('dirName', 'Rufat Gasanov'), ('publicationYear', '2010'), ('numFilms', '1')]
# [('dir', 'http://www.wikidata.org/entity/Q11754938'), ('dirName', 'Leszek Dawid'), ('publicationYear', '2012'), ('numFilms', '1')]
# [('dir', 'http://www.wikidata.org/entity/Q6843606'), ('dirName', 'Mieczysław Krawicz'), ('publicationYear', '1937'), ('numFilms', '2')]
# 50

# %%
# write your queries
# director (P57)
# film (Q11424)
# publication date (P577)
# Woody Allen (Q25089)
# Quentin Tarantino (Q3772)
# let's search all the films whom director is Woody Allen
# let's find publication year of each film
# let's try to find with first date of publication because some are showing with double
# we need to Consider only films directed by Woody Allen or Quentin Tarantino
queryString = """
SELECT DISTINCT ?dir ?dirName (YEAR(?date) AS ?publicationYear) (COUNT(?film) AS ?numFilms)
WHERE {
   # bind something
   # ?film wdt:P57 ?dir;
       wdt:P31 wd:Q11424 ;
       wdt:P577 ?date.
   # ?dir sc:name ?dirName
   FILTER(?dir=wd:Q25089 || ?dir=wd:Q3772)
   filter NOT EXISTS{
       # ?film wdt:P577 ?secondDate .
       filter(?secondDate < ?date) .
   }
   # get the label
  # ?film sc:name ?filmName.
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('dir', 'http://www.wikidata.org/entity/Q3772'), ('dirName', 'Quentin Tarantino'), ('publicationYear', '1994'), ('numFilms', '1')]
# [('dir', 'http://www.wikidata.org/entity/Q3772'), ('dirName', 'Quentin Tarantino'), ('publicationYear', '2012'), ('numFilms', '1')]
# [('dir', 'http://www.wikidata.org/entity/Q25089'), ('dirName', 'Woody Allen'), ('publicationYear', '2001'), ('numFilms', '2')]
# [('dir', 'http://www.wikidata.org/entity/Q25089'), ('dirName', 'Woody Allen'), ('publicationYear', '1966'), ('numFilms', '1')]
# [('dir', 'http://www.wikidata.org/entity/Q25089'), ('dirName', 'Woody Allen'), ('publicationYear', '2000'), ('numFilms', '1')]
# [('dir', 'http://www.wikidata.org/entity/Q25089'), ('dirName', 'Woody Allen'), ('publicationYear', '2016'), ('numFilms', '1')]
# [('dir', 'http://www.wikidata.org/entity/Q25089'), ('dirName', 'Woody Allen'), ('publicationYear', '1982'), ('numFilms', '1')]
# [('dir', 'http://www.wikidata.org/entity/Q3772'), ('dirName', 'Quentin Tarantino'), ('publicationYear', '2019'), ('numFilms', '1')]
# [('dir', 'http://www.wikidata.org/entity/Q25089'), ('dirName', 'Woody Allen'), ('publicationYear', '1994'), ('numFilms', '1')]
# [('dir', 'http://www.wikidata.org/entity/Q25089'), ('dirName', 'Woody Allen'), ('publicationYear', '1983'), ('numFilms', '1')]
# [('dir', 'http://www.wikidata.org/entity/Q25089'), ('dirName', 'Woody Allen'), ('publicationYear', '1973'), ('numFilms', '1')]
# [('dir', 'http://www.wikidata.org/entity/Q25089'), ('dirName', 'Woody Allen'), ('publicationYear', '2015'), ('numFilms', '1')]
# [('dir', 'http://www.wikidata.org/entity/Q25089'), ('dirName', 'Woody Allen'), ('publicationYear', '2012'), ('numFilms', '1')]
# [('dir', 'http://www.wikidata.org/entity/Q25089'), ('dirName', 'Woody Allen'), ('publicationYear', '2008'), ('numFilms', '1')]
# [('dir', 'http://www.wikidata.org/entity/Q25089'), ('dirName', 'Woody Allen'), ('publicationYear', '1978'), ('numFilms', '1')]
# [('dir', 'http://www.wikidata.org/entity/Q25089'), ('dirName', 'Woody Allen'), ('publicationYear', '1975'), ('numFilms', '1')]
# [('dir', 'http://www.wikidata.org/entity/Q25089'), ('dirName', 'Woody Allen'), ('publicationYear', '1991'), ('numFilms', '1')]
# [('dir', 'http://www.wikidata.org/entity/Q25089'), ('dirName', 'Woody Allen'), ('publicationYear', '1979'), ('numFilms', '1')]
# [('dir', 'http://www.wikidata.org/entity/Q25089'), ('dirName', 'Woody Allen'), ('publicationYear', '1972'), ('numFilms', '1')]
# [('dir', 'http://www.wikidata.org/entity/Q25089'), ('dirName', 'Woody Allen'), ('publicationYear', '2019'), ('numFilms', '1')]
# [('dir', 'http://www.wikidata.org/entity/Q3772'), ('dirName', 'Quentin Tarantino'), ('publicationYear', '2007'), ('numFilms', '1')]
# [('dir', 'http://www.wikidata.org/entity/Q25089'), ('dirName', 'Woody Allen'), ('publicationYear', '1995'), ('numFilms', '1')]
# [('dir', 'http://www.wikidata.org/entity/Q25089'), ('dirName', 'Woody Allen'), ('publicationYear', '2005'), ('numFilms', '1')]
# [('dir', 'http://www.wikidata.org/entity/Q25089'), ('dirName', 'Woody Allen'), ('publicationYear', '2007'), ('numFilms', '1')]
# [('dir', 'http://www.wikidata.org/entity/Q25089'), ('dirName', 'Woody Allen'), ('publicationYear', '1988'), ('numFilms', '1')]
# [('dir', 'http://www.wikidata.org/entity/Q3772'), ('dirName', 'Quentin Tarantino'), ('publicationYear', '2003'), ('numFilms', '1')]
# [('dir', 'http://www.wikidata.org/entity/Q25089'), ('dirName', 'Woody Allen'), ('publicationYear', '1992'), ('numFilms', '1')]
# [('dir', 'http://www.wikidata.org/entity/Q25089'), ('dirName', 'Woody Allen'), ('publicationYear', '2014'), ('numFilms', '1')]
# [('dir', 'http://www.wikidata.org/entity/Q25089'), ('dirName', 'Woody Allen'), ('publicationYear', '2013'), ('numFilms', '1')]
# [('dir', 'http://www.wikidata.org/entity/Q25089'), ('dirName', 'Woody Allen'), ('publicationYear', '1986'), ('numFilms', '1')]
# [('dir', 'http://www.wikidata.org/entity/Q3772'), ('dirName', 'Quentin Tarantino'), ('publicationYear', '2015'), ('numFilms', '1')]
# [('dir', 'http://www.wikidata.org/entity/Q3772'), ('dirName', 'Quentin Tarantino'), ('publicationYear', '2009'), ('numFilms', '1')]
# [('dir', 'http://www.wikidata.org/entity/Q25089'), ('dirName', 'Woody Allen'), ('publicationYear', '1984'), ('numFilms', '1')]
# [('dir', 'http://www.wikidata.org/entity/Q25089'), ('dirName', 'Woody Allen'), ('publicationYear', '2010'), ('numFilms', '1')]
# [('dir', 'http://www.wikidata.org/entity/Q25089'), ('dirName', 'Woody Allen'), ('publicationYear', '2003'), ('numFilms', '1')]
# [('dir', 'http://www.wikidata.org/entity/Q25089'), ('dirName', 'Woody Allen'), ('publicationYear', '1969'), ('numFilms', '1')]
# [('dir', 'http://www.wikidata.org/entity/Q25089'), ('dirName', 'Woody Allen'), ('publicationYear', '2002'), ('numFilms', '1')]
# [('dir', 'http://www.wikidata.org/entity/Q3772'), ('dirName', 'Quentin Tarantino'), ('publicationYear', '1992'), ('numFilms', '1')]
# [('dir', 'http://www.wikidata.org/entity/Q25089'), ('dirName', 'Woody Allen'), ('publicationYear', '1985'), ('numFilms', '1')]
# [('dir', 'http://www.wikidata.org/entity/Q3772'), ('dirName', 'Quentin Tarantino'), ('publicationYear', '2005'), ('numFilms', '1')]
# [('dir', 'http://www.wikidata.org/entity/Q25089'), ('dirName', 'Woody Allen'), ('publicationYear', '2011'), ('numFilms', '1')]
# [('dir', 'http://www.wikidata.org/entity/Q25089'), ('dirName', 'Woody Allen'), ('publicationYear', '1998'), ('numFilms', '1')]
# [('dir', 'http://www.wikidata.org/entity/Q25089'), ('dirName', 'Woody Allen'), ('publicationYear', '1989'), ('numFilms', '2')]
# [('dir', 'http://www.wikidata.org/entity/Q25089'), ('dirName', 'Woody Allen'), ('publicationYear', '1993'), ('numFilms', '1')]
# [('dir', 'http://www.wikidata.org/entity/Q25089'), ('dirName', 'Woody Allen'), ('publicationYear', '2004'), ('numFilms', '1')]
# [('dir', 'http://www.wikidata.org/entity/Q3772'), ('dirName', 'Quentin Tarantino'), ('publicationYear', '1997'), ('numFilms', '1')]
# [('dir', 'http://www.wikidata.org/entity/Q3772'), ('dirName', 'Quentin Tarantino'), ('publicationYear', '2004'), ('numFilms', '1')]
# [('dir', 'http://www.wikidata.org/entity/Q25089'), ('dirName', 'Woody Allen'), ('publicationYear', '2006'), ('numFilms', '1')]
# [('dir', 'http://www.wikidata.org/entity/Q25089'), ('dirName', 'Woody Allen'), ('publicationYear', '1980'), ('numFilms', '1')]
# [('dir', 'http://www.wikidata.org/entity/Q25089'), ('dirName', 'Woody Allen'), ('publicationYear', '1996'), ('numFilms', '1')]
# [('dir', 'http://www.wikidata.org/entity/Q25089'), ('dirName', 'Woody Allen'), ('publicationYear', '1997'), ('numFilms', '1')]
# [('dir', 'http://www.wikidata.org/entity/Q25089'), ('dirName', 'Woody Allen'), ('publicationYear', '1971'), ('numFilms', '1')]
# [('dir', 'http://www.wikidata.org/entity/Q25089'), ('dirName', 'Woody Allen'), ('publicationYear', '2017'), ('numFilms', '1')]
# [('dir', 'http://www.wikidata.org/entity/Q25089'), ('dirName', 'Woody Allen'), ('publicationYear', '1999'), ('numFilms', '1')]
# [('dir', 'http://www.wikidata.org/entity/Q25089'), ('dirName', 'Woody Allen'), ('publicationYear', '1987'), ('numFilms', '2')]
# [('dir', 'http://www.wikidata.org/entity/Q25089'), ('dirName', 'Woody Allen'), ('publicationYear', '1977'), ('numFilms', '1')]
# [('dir', 'http://www.wikidata.org/entity/Q25089'), ('dirName', 'Woody Allen'), ('publicationYear', '1990'), ('numFilms', '1')]
# [('dir', 'http://www.wikidata.org/entity/Q25089'), ('dirName', 'Woody Allen'), ('publicationYear', '2020'), ('numFilms', '1')]
# [('dir', 'http://www.wikidata.org/entity/Q25089'), ('dirName', 'Woody Allen'), ('publicationYear', '2009'), ('numFilms', '1')]
# 59

# %% [markdown]
# Final query for this task

# %%
# # write your final query
# director (P57)
# film (Q11424)
# publication date (P577)
# Woody Allen (Q25089)
# Quentin Tarantino (Q3772)
# let's search all the films whom director is Woody Allen
# let's find publication year of each film
# let's try to find with first date of publication because some are showing with double
# we need to Consider only films directed by Woody Allen or Quentin Tarantino
queryString = """
SELECT DISTINCT ?dir ?dirName (YEAR(?date) AS ?publicationYear) (COUNT(?film) AS ?numFilms)
WHERE {
   # bind something
   # ?film wdt:P57 ?dir;
       wdt:P31 wd:Q11424 ;
       wdt:P577 ?date.
   # ?dir sc:name ?dirName
   FILTER(?dir=wd:Q25089 || ?dir=wd:Q3772)
   filter NOT EXISTS{
       # ?film wdt:P577 ?secondDate .
       filter(?secondDate < ?date) .
   }
   # get the label
  # ?film sc:name ?filmName.
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('dir', 'http://www.wikidata.org/entity/Q3772'), ('dirName', 'Quentin Tarantino'), ('publicationYear', '1994'), ('numFilms', '1')]
# [('dir', 'http://www.wikidata.org/entity/Q3772'), ('dirName', 'Quentin Tarantino'), ('publicationYear', '2012'), ('numFilms', '1')]
# [('dir', 'http://www.wikidata.org/entity/Q25089'), ('dirName', 'Woody Allen'), ('publicationYear', '2001'), ('numFilms', '2')]
# [('dir', 'http://www.wikidata.org/entity/Q25089'), ('dirName', 'Woody Allen'), ('publicationYear', '1966'), ('numFilms', '1')]
# [('dir', 'http://www.wikidata.org/entity/Q25089'), ('dirName', 'Woody Allen'), ('publicationYear', '2000'), ('numFilms', '1')]
# [('dir', 'http://www.wikidata.org/entity/Q25089'), ('dirName', 'Woody Allen'), ('publicationYear', '2016'), ('numFilms', '1')]
# [('dir', 'http://www.wikidata.org/entity/Q25089'), ('dirName', 'Woody Allen'), ('publicationYear', '1982'), ('numFilms', '1')]
# [('dir', 'http://www.wikidata.org/entity/Q3772'), ('dirName', 'Quentin Tarantino'), ('publicationYear', '2019'), ('numFilms', '1')]
# [('dir', 'http://www.wikidata.org/entity/Q25089'), ('dirName', 'Woody Allen'), ('publicationYear', '1994'), ('numFilms', '1')]
# [('dir', 'http://www.wikidata.org/entity/Q25089'), ('dirName', 'Woody Allen'), ('publicationYear', '1983'), ('numFilms', '1')]
# [('dir', 'http://www.wikidata.org/entity/Q25089'), ('dirName', 'Woody Allen'), ('publicationYear', '1973'), ('numFilms', '1')]
# [('dir', 'http://www.wikidata.org/entity/Q25089'), ('dirName', 'Woody Allen'), ('publicationYear', '2015'), ('numFilms', '1')]
# [('dir', 'http://www.wikidata.org/entity/Q25089'), ('dirName', 'Woody Allen'), ('publicationYear', '2012'), ('numFilms', '1')]
# [('dir', 'http://www.wikidata.org/entity/Q25089'), ('dirName', 'Woody Allen'), ('publicationYear', '2008'), ('numFilms', '1')]
# [('dir', 'http://www.wikidata.org/entity/Q25089'), ('dirName', 'Woody Allen'), ('publicationYear', '1978'), ('numFilms', '1')]
# [('dir', 'http://www.wikidata.org/entity/Q25089'), ('dirName', 'Woody Allen'), ('publicationYear', '1975'), ('numFilms', '1')]
# [('dir', 'http://www.wikidata.org/entity/Q25089'), ('dirName', 'Woody Allen'), ('publicationYear', '1991'), ('numFilms', '1')]
# [('dir', 'http://www.wikidata.org/entity/Q25089'), ('dirName', 'Woody Allen'), ('publicationYear', '1979'), ('numFilms', '1')]
# [('dir', 'http://www.wikidata.org/entity/Q25089'), ('dirName', 'Woody Allen'), ('publicationYear', '1972'), ('numFilms', '1')]
# [('dir', 'http://www.wikidata.org/entity/Q25089'), ('dirName', 'Woody Allen'), ('publicationYear', '2019'), ('numFilms', '1')]
# [('dir', 'http://www.wikidata.org/entity/Q3772'), ('dirName', 'Quentin Tarantino'), ('publicationYear', '2007'), ('numFilms', '1')]
# [('dir', 'http://www.wikidata.org/entity/Q25089'), ('dirName', 'Woody Allen'), ('publicationYear', '1995'), ('numFilms', '1')]
# [('dir', 'http://www.wikidata.org/entity/Q25089'), ('dirName', 'Woody Allen'), ('publicationYear', '2005'), ('numFilms', '1')]
# [('dir', 'http://www.wikidata.org/entity/Q25089'), ('dirName', 'Woody Allen'), ('publicationYear', '2007'), ('numFilms', '1')]
# [('dir', 'http://www.wikidata.org/entity/Q25089'), ('dirName', 'Woody Allen'), ('publicationYear', '1988'), ('numFilms', '1')]
# [('dir', 'http://www.wikidata.org/entity/Q3772'), ('dirName', 'Quentin Tarantino'), ('publicationYear', '2003'), ('numFilms', '1')]
# [('dir', 'http://www.wikidata.org/entity/Q25089'), ('dirName', 'Woody Allen'), ('publicationYear', '1992'), ('numFilms', '1')]
# [('dir', 'http://www.wikidata.org/entity/Q25089'), ('dirName', 'Woody Allen'), ('publicationYear', '2014'), ('numFilms', '1')]
# [('dir', 'http://www.wikidata.org/entity/Q25089'), ('dirName', 'Woody Allen'), ('publicationYear', '2013'), ('numFilms', '1')]
# [('dir', 'http://www.wikidata.org/entity/Q25089'), ('dirName', 'Woody Allen'), ('publicationYear', '1986'), ('numFilms', '1')]
# [('dir', 'http://www.wikidata.org/entity/Q3772'), ('dirName', 'Quentin Tarantino'), ('publicationYear', '2015'), ('numFilms', '1')]
# [('dir', 'http://www.wikidata.org/entity/Q3772'), ('dirName', 'Quentin Tarantino'), ('publicationYear', '2009'), ('numFilms', '1')]
# [('dir', 'http://www.wikidata.org/entity/Q25089'), ('dirName', 'Woody Allen'), ('publicationYear', '1984'), ('numFilms', '1')]
# [('dir', 'http://www.wikidata.org/entity/Q25089'), ('dirName', 'Woody Allen'), ('publicationYear', '2010'), ('numFilms', '1')]
# [('dir', 'http://www.wikidata.org/entity/Q25089'), ('dirName', 'Woody Allen'), ('publicationYear', '2003'), ('numFilms', '1')]
# [('dir', 'http://www.wikidata.org/entity/Q25089'), ('dirName', 'Woody Allen'), ('publicationYear', '1969'), ('numFilms', '1')]
# [('dir', 'http://www.wikidata.org/entity/Q25089'), ('dirName', 'Woody Allen'), ('publicationYear', '2002'), ('numFilms', '1')]
# [('dir', 'http://www.wikidata.org/entity/Q3772'), ('dirName', 'Quentin Tarantino'), ('publicationYear', '1992'), ('numFilms', '1')]
# [('dir', 'http://www.wikidata.org/entity/Q25089'), ('dirName', 'Woody Allen'), ('publicationYear', '1985'), ('numFilms', '1')]
# [('dir', 'http://www.wikidata.org/entity/Q3772'), ('dirName', 'Quentin Tarantino'), ('publicationYear', '2005'), ('numFilms', '1')]
# [('dir', 'http://www.wikidata.org/entity/Q25089'), ('dirName', 'Woody Allen'), ('publicationYear', '2011'), ('numFilms', '1')]
# [('dir', 'http://www.wikidata.org/entity/Q25089'), ('dirName', 'Woody Allen'), ('publicationYear', '1998'), ('numFilms', '1')]
# [('dir', 'http://www.wikidata.org/entity/Q25089'), ('dirName', 'Woody Allen'), ('publicationYear', '1989'), ('numFilms', '2')]
# [('dir', 'http://www.wikidata.org/entity/Q25089'), ('dirName', 'Woody Allen'), ('publicationYear', '1993'), ('numFilms', '1')]
# [('dir', 'http://www.wikidata.org/entity/Q25089'), ('dirName', 'Woody Allen'), ('publicationYear', '2004'), ('numFilms', '1')]
# [('dir', 'http://www.wikidata.org/entity/Q3772'), ('dirName', 'Quentin Tarantino'), ('publicationYear', '1997'), ('numFilms', '1')]
# [('dir', 'http://www.wikidata.org/entity/Q3772'), ('dirName', 'Quentin Tarantino'), ('publicationYear', '2004'), ('numFilms', '1')]
# [('dir', 'http://www.wikidata.org/entity/Q25089'), ('dirName', 'Woody Allen'), ('publicationYear', '2006'), ('numFilms', '1')]
# [('dir', 'http://www.wikidata.org/entity/Q25089'), ('dirName', 'Woody Allen'), ('publicationYear', '1980'), ('numFilms', '1')]
# [('dir', 'http://www.wikidata.org/entity/Q25089'), ('dirName', 'Woody Allen'), ('publicationYear', '1996'), ('numFilms', '1')]
# [('dir', 'http://www.wikidata.org/entity/Q25089'), ('dirName', 'Woody Allen'), ('publicationYear', '1997'), ('numFilms', '1')]
# [('dir', 'http://www.wikidata.org/entity/Q25089'), ('dirName', 'Woody Allen'), ('publicationYear', '1971'), ('numFilms', '1')]
# [('dir', 'http://www.wikidata.org/entity/Q25089'), ('dirName', 'Woody Allen'), ('publicationYear', '2017'), ('numFilms', '1')]
# [('dir', 'http://www.wikidata.org/entity/Q25089'), ('dirName', 'Woody Allen'), ('publicationYear', '1999'), ('numFilms', '1')]
# [('dir', 'http://www.wikidata.org/entity/Q25089'), ('dirName', 'Woody Allen'), ('publicationYear', '1987'), ('numFilms', '2')]
# [('dir', 'http://www.wikidata.org/entity/Q25089'), ('dirName', 'Woody Allen'), ('publicationYear', '1977'), ('numFilms', '1')]
# [('dir', 'http://www.wikidata.org/entity/Q25089'), ('dirName', 'Woody Allen'), ('publicationYear', '1990'), ('numFilms', '1')]
# [('dir', 'http://www.wikidata.org/entity/Q25089'), ('dirName', 'Woody Allen'), ('publicationYear', '2020'), ('numFilms', '1')]
# [('dir', 'http://www.wikidata.org/entity/Q25089'), ('dirName', 'Woody Allen'), ('publicationYear', '2009'), ('numFilms', '1')]
# 59

# %% [markdown]
# ## Task 6
# Identify the BGP for Academy Awards

# %%
# write your queries
# let's look to first query
queryString = """
SELECT DISTINCT ?obj ?name
WHERE {
   # bind something
   wd:Q3772 ?p ?obj .
   # get the label
   # ?obj sc:name ?name.
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('obj', 'http://www.wikidata.org/entity/Q212026'), ('name', 'Mira Sorvino')]
# [('obj', 'http://www.wikidata.org/entity/Q2566554'), ('name', '48th British Academy Film Awards')]
# [('obj', 'http://www.wikidata.org/entity/Q833154'), ('name', 'Edgar Awards')]
# [('obj', 'http://www.wikidata.org/entity/Q103360'), ('name', 'Academy Award for Best Director')]
# [('obj', 'http://www.wikidata.org/entity/Q10798782'), ('name', 'television actor')]
# [('obj', 'http://www.wikidata.org/entity/Q10800557'), ('name', 'film actor')]
# [('obj', 'http://www.wikidata.org/entity/Q113068'), ('name', 'Hungarian Order of Merit')]
# [('obj', 'http://www.wikidata.org/entity/Q13452531'), ('name', 'Commandeur des Arts et des Lettres\u200e')]
# [('obj', 'http://www.wikidata.org/entity/Q17290934'), ('name', 'Lentapedia')]
# [('obj', 'http://www.wikidata.org/entity/Q179808'), ('name', "Palme d'Or")]
# [('obj', 'http://www.wikidata.org/entity/Q17985761'), ('name', 'star on Hollywood Walk of Fame')]
# [('obj', 'http://www.wikidata.org/entity/Q1860'), ('name', 'English')]
# [('obj', 'http://www.wikidata.org/entity/Q188'), ('name', 'German')]
# [('obj', 'http://www.wikidata.org/entity/Q188473'), ('name', 'action film')]
# [('obj', 'http://www.wikidata.org/entity/Q188740'), ('name', 'Museum of Modern Art')]
# [('obj', 'http://www.wikidata.org/entity/Q2526255'), ('name', 'film director')]
# [('obj', 'http://www.wikidata.org/entity/Q28389'), ('name', 'screenwriter')]
# [('obj', 'http://www.wikidata.org/entity/Q30'), ('name', 'United States of America')]
# [('obj', 'http://www.wikidata.org/entity/Q3282637'), ('name', 'film producer')]
# [('obj', 'http://www.wikidata.org/entity/Q33999'), ('name', 'actor')]
# [('obj', 'http://www.wikidata.org/entity/Q3455803'), ('name', 'director')]
# [('obj', 'http://www.wikidata.org/entity/Q36180'), ('name', 'writer')]
# [('obj', 'http://www.wikidata.org/entity/Q41417'), ('name', 'Academy Award for Best Writing, Original Screenplay')]
# [('obj', 'http://www.wikidata.org/entity/Q463303'), ('name', 'American Academy of Arts and Sciences')]
# [('obj', 'http://www.wikidata.org/entity/Q490861'), ('name', '70th Golden Globe Awards')]
# [('obj', 'http://www.wikidata.org/entity/Q5'), ('name', 'human')]
# [('obj', 'http://www.wikidata.org/entity/Q5043'), ('name', 'Christianity')]
# [('obj', 'http://www.wikidata.org/entity/Q52382875'), ('name', 'AAAS Fellow')]
# [('obj', 'http://www.wikidata.org/entity/Q6581097'), ('name', 'male')]
# [('obj', 'http://www.wikidata.org/entity/Q67311526'), ('name', 'Obalky knih.cz')]
# [('obj', 'http://www.wikidata.org/entity/Q7042855'), ('name', 'film editor')]
# [('obj', 'http://www.wikidata.org/entity/Q73555012'), ('name', 'works protected by copyrights')]
# [('obj', 'http://www.wikidata.org/entity/Q1377772'), ('name', 'European Film Award for Best Non-European Film')]
# [('obj', 'http://www.wikidata.org/entity/Q1789102'), ('name', 'National Board of Review Award for Best Film')]
# [('obj', 'http://www.wikidata.org/entity/Q23958341'), ('name', 'President of the Jury at the Cannes Festival')]
# [('obj', 'http://www.wikidata.org/entity/Q974693'), ('name', 'Italian American')]
# [('obj', 'http://www.wikidata.org/entity/Q1075293'), ('name', 'Irish Americans')]
# [('obj', 'http://www.wikidata.org/entity/Q185582'), ('name', 'Knoxville')]
# [('obj', 'http://www.wikidata.org/entity/Q51581'), ('name', 'Howard Hawks')]
# [('obj', 'http://www.wikidata.org/entity/Q41375'), ('name', 'BAFTA Award for Best Original Screenplay')]
# [('obj', 'http://www.wikidata.org/entity/Q849124'), ('name', 'Golden Globe Award for Best Screenplay')]
# [('obj', 'http://www.wikidata.org/entity/Q93439'), ('name', '52nd Golden Globe Awards')]
# [('obj', 'http://www.wikidata.org/entity/Q459290'), ('name', 'independent film')]
# [('obj', 'http://www.wikidata.org/entity/Q1158484'), ('name', 'Quentin')]
# [('obj', 'http://www.wikidata.org/entity/Q21487819'), ('name', 'Tarantino')]
# [('obj', 'http://www.wikidata.org/entity/Q3404975'), ('name', 'Lumière Award, Lyon Festival of cinema')]
# [('obj', 'http://www.wikidata.org/entity/Q245949'), ('name', '36th César Awards')]
# [('obj', 'http://www.wikidata.org/entity/Q32947601'), ('name', 'Daniella Pick')]
# [('obj', 'http://www.wikidata.org/entity/Q2690424'), ('name', '66th British Academy Film Awards')]
# [('obj', 'http://www.wikidata.org/entity/Q5274115'), ('name', 'Didem Erol')]
# [('obj', 'http://www.wikidata.org/entity/Q4818309'), ('name', 'Tony Tarantino')]
# [('obj', 'http://www.wikidata.org/entity/Q6489997'), ('name', 'Template:Quentin Tarantino')]
# [('obj', 'http://www.wikidata.org/entity/Q6838938'), ('name', 'Category:Films directed by Quentin Tarantino')]
# [('obj', 'http://www.wikidata.org/entity/Q10113292'), ('name', 'Category:Quentin Tarantino')]
# [('obj', 'http://www.wikidata.org/entity/Q6794012'), ('name', 'Quentin Tarantino filmography')]
# [('obj', 'http://www.wikidata.org/entity/Q7005534'), ('name', 'New Beverly Cinema')]
# 56

# %%
# write your queries
# let's look to first query
# [('obj', 'http://www.wikidata.org/entity/Q103360'), ('name', 'Academy Award for Best Director')]
queryString = """
SELECT DISTINCT ?obj ?name
WHERE {
   # bind something
   wd:Q103360 ?p ?obj .
   # get the label
   # ?obj sc:name ?name.
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('obj', 'http://www.wikidata.org/entity/Q96474679'), ('name', 'award for best direction')]
# [('obj', 'http://www.wikidata.org/entity/Q160726'), ('name', 'Ang Lee')]
# [('obj', 'http://www.wikidata.org/entity/Q55215'), ('name', 'Alejandro González Iñárritu')]
# [('obj', 'http://www.wikidata.org/entity/Q19020'), ('name', 'Academy Awards')]
# [('obj', 'http://www.wikidata.org/entity/Q30'), ('name', 'United States of America')]
# [('obj', 'http://www.wikidata.org/entity/Q28028'), ('name', 'Alfonso Cuarón')]
# [('obj', 'http://www.wikidata.org/entity/Q212329'), ('name', 'Academy of Motion Picture Arts and Sciences')]
# [('obj', 'http://www.wikidata.org/entity/Q7146100'), ('name', 'Category:Best Directing Academy Award winners')]
# [('obj', 'http://www.wikidata.org/entity/Q6667698'), ('name', 'Template:Academy Award for Best Director')]
# [('obj', 'http://www.wikidata.org/entity/Q495980'), ('name', 'Bong Joon-ho')]
# 10

# %%
# write your queries
# let's look to first query
# [('obj', 'http://www.wikidata.org/entity/Q103360'), ('name', 'Academy Award for Best Director')]
queryString = """
SELECT DISTINCT ?obj ?name
WHERE {
   # bind something
   wd:Q103360 ?p ?obj .
   # get the label
   # ?obj sc:name ?name.
   filter(regex(?name, "Academy Awards"))
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('obj', 'http://www.wikidata.org/entity/Q19020'), ('name', 'Academy Awards')]
# 1

# %% [markdown]
# Final query for this task

# %%
# write your queries
# # write your final query
# [('obj', 'http://www.wikidata.org/entity/Q103360'), ('name', 'Academy Award for Best Director')]
queryString = """
SELECT DISTINCT ?obj ?name
WHERE {
   # bind something
   wd:Q103360 ?p ?obj .
   # get the label
   # ?obj sc:name ?name.
   filter(regex(?name, "Academy Awards"))
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('obj', 'http://www.wikidata.org/entity/Q19020'), ('name', 'Academy Awards')]
# 1

# %% [markdown]
# ## Task 7
# Consider films directed by Woody Allen or Quentin Tarantino separately. Return the film which won more Academy Awards for the two directors (the result set must be two elements - one related to Allen and the other related to Tarantino -  and for each element there must be present the director IRI with its label, the film IRI with its label and the number of Academy awards won).

# %%
# write your queries
# Academy Awards (Q19020)
# film (Q11424)
# award received (P166)
# director (P57)
# let's find academy awards won by films and also find director name
queryString = """
SELECT DISTINCT ?director ?directorName ?film ?filmName ?academyAward ?academyAwardName
WHERE {
    # ?academyAward wdt:P31 wd:Q19020 .
    # ?film wdt:P31 wd:Q11424;
        wdt:P57 ?director ;
        wdt:P166 ?academyAward .
        
    # ?director sc:name ?directorName .
    # ?film sc:name ?filmName .
    # ?academyAward sc:name ?academyAwardName .
    filter (?director=wd:Q25089 || ?director=wd:Q3772)
}
LIMIT 100

"""
print("Results")
x=run_query(queryString)
# Out:
# Results
# [('director', 'http://www.wikidata.org/entity/Q3772'), ('directorName', 'Quentin Tarantino'), ('film', 'http://www.wikidata.org/entity/Q153723'), ('filmName', 'Inglourious Basterds'), ('academyAward', 'http://www.wikidata.org/entity/Q106291'), ('academyAwardName', 'Academy Award for Best Supporting Actor')]
# [('director', 'http://www.wikidata.org/entity/Q3772'), ('directorName', 'Quentin Tarantino'), ('film', 'http://www.wikidata.org/entity/Q47300912'), ('filmName', 'Once Upon a Time in Hollywood'), ('academyAward', 'http://www.wikidata.org/entity/Q106291'), ('academyAwardName', 'Academy Award for Best Supporting Actor')]
# [('director', 'http://www.wikidata.org/entity/Q3772'), ('directorName', 'Quentin Tarantino'), ('film', 'http://www.wikidata.org/entity/Q104123'), ('filmName', 'Pulp Fiction'), ('academyAward', 'http://www.wikidata.org/entity/Q41417'), ('academyAwardName', 'Academy Award for Best Writing, Original Screenplay')]
# [('director', 'http://www.wikidata.org/entity/Q3772'), ('directorName', 'Quentin Tarantino'), ('film', 'http://www.wikidata.org/entity/Q571032'), ('filmName', 'Django Unchained'), ('academyAward', 'http://www.wikidata.org/entity/Q106291'), ('academyAwardName', 'Academy Award for Best Supporting Actor')]
# [('director', 'http://www.wikidata.org/entity/Q3772'), ('directorName', 'Quentin Tarantino'), ('film', 'http://www.wikidata.org/entity/Q18225084'), ('filmName', 'The Hateful Eight'), ('academyAward', 'http://www.wikidata.org/entity/Q488651'), ('academyAwardName', 'Academy Award for Best Original Score')]
# [('director', 'http://www.wikidata.org/entity/Q3772'), ('directorName', 'Quentin Tarantino'), ('film', 'http://www.wikidata.org/entity/Q571032'), ('filmName', 'Django Unchained'), ('academyAward', 'http://www.wikidata.org/entity/Q41417'), ('academyAwardName', 'Academy Award for Best Writing, Original Screenplay')]
# [('director', 'http://www.wikidata.org/entity/Q3772'), ('directorName', 'Quentin Tarantino'), ('film', 'http://www.wikidata.org/entity/Q47300912'), ('filmName', 'Once Upon a Time in Hollywood'), ('academyAward', 'http://www.wikidata.org/entity/Q277751'), ('academyAwardName', 'Academy Award for Best Production Design')]
# [('director', 'http://www.wikidata.org/entity/Q25089'), ('directorName', 'Woody Allen'), ('film', 'http://www.wikidata.org/entity/Q233464'), ('filmName', 'Annie Hall'), ('academyAward', 'http://www.wikidata.org/entity/Q103360'), ('academyAwardName', 'Academy Award for Best Director')]
# [('director', 'http://www.wikidata.org/entity/Q25089'), ('directorName', 'Woody Allen'), ('film', 'http://www.wikidata.org/entity/Q1354109'), ('filmName', 'Mighty Aphrodite'), ('academyAward', 'http://www.wikidata.org/entity/Q106301'), ('academyAwardName', 'Academy Award for Best Supporting Actress')]
# [('director', 'http://www.wikidata.org/entity/Q25089'), ('directorName', 'Woody Allen'), ('film', 'http://www.wikidata.org/entity/Q845057'), ('filmName', 'Hannah and Her Sisters'), ('academyAward', 'http://www.wikidata.org/entity/Q106291'), ('academyAwardName', 'Academy Award for Best Supporting Actor')]
# [('director', 'http://www.wikidata.org/entity/Q25089'), ('directorName', 'Woody Allen'), ('film', 'http://www.wikidata.org/entity/Q206124'), ('filmName', 'Midnight in Paris'), ('academyAward', 'http://www.wikidata.org/entity/Q41417'), ('academyAwardName', 'Academy Award for Best Writing, Original Screenplay')]
# [('director', 'http://www.wikidata.org/entity/Q25089'), ('directorName', 'Woody Allen'), ('film', 'http://www.wikidata.org/entity/Q233464'), ('filmName', 'Annie Hall'), ('academyAward', 'http://www.wikidata.org/entity/Q103618'), ('academyAwardName', 'Academy Award for Best Actress')]
# [('director', 'http://www.wikidata.org/entity/Q25089'), ('directorName', 'Woody Allen'), ('film', 'http://www.wikidata.org/entity/Q212123'), ('filmName', 'Vicky Cristina Barcelona'), ('academyAward', 'http://www.wikidata.org/entity/Q106301'), ('academyAwardName', 'Academy Award for Best Supporting Actress')]
# [('director', 'http://www.wikidata.org/entity/Q25089'), ('directorName', 'Woody Allen'), ('film', 'http://www.wikidata.org/entity/Q845057'), ('filmName', 'Hannah and Her Sisters'), ('academyAward', 'http://www.wikidata.org/entity/Q106301'), ('academyAwardName', 'Academy Award for Best Supporting Actress')]
# [('director', 'http://www.wikidata.org/entity/Q25089'), ('directorName', 'Woody Allen'), ('film', 'http://www.wikidata.org/entity/Q2907178'), ('filmName', 'Blue Jasmine'), ('academyAward', 'http://www.wikidata.org/entity/Q103618'), ('academyAwardName', 'Academy Award for Best Actress')]
# [('director', 'http://www.wikidata.org/entity/Q25089'), ('directorName', 'Woody Allen'), ('film', 'http://www.wikidata.org/entity/Q233464'), ('filmName', 'Annie Hall'), ('academyAward', 'http://www.wikidata.org/entity/Q102427'), ('academyAwardName', 'Academy Award for Best Picture')]
# [('director', 'http://www.wikidata.org/entity/Q25089'), ('directorName', 'Woody Allen'), ('film', 'http://www.wikidata.org/entity/Q1004531'), ('filmName', 'Bullets Over Broadway'), ('academyAward', 'http://www.wikidata.org/entity/Q106301'), ('academyAwardName', 'Academy Award for Best Supporting Actress')]
# [('director', 'http://www.wikidata.org/entity/Q25089'), ('directorName', 'Woody Allen'), ('film', 'http://www.wikidata.org/entity/Q845057'), ('filmName', 'Hannah and Her Sisters'), ('academyAward', 'http://www.wikidata.org/entity/Q41417'), ('academyAwardName', 'Academy Award for Best Writing, Original Screenplay')]
# [('director', 'http://www.wikidata.org/entity/Q25089'), ('directorName', 'Woody Allen'), ('film', 'http://www.wikidata.org/entity/Q233464'), ('filmName', 'Annie Hall'), ('academyAward', 'http://www.wikidata.org/entity/Q41417'), ('academyAwardName', 'Academy Award for Best Writing, Original Screenplay')]
# 19

# %%
# write your queries
# Academy Awards (Q19020)
# film (Q11424)
# award received (P166)
# director (P57)
# let's find academy awards won by films and also find director name
#group by director and film as well as count number of awards
queryString = """
SELECT DISTINCT ?director ?directorName ?film ?filmName (COUNT(?academyAward) as ?totalAwards)
WHERE {
    # ?academyAward wdt:P31 wd:Q19020 .
    # ?film wdt:P31 wd:Q11424;
        wdt:P57 ?director ;
        wdt:P166 ?academyAward .
        
    # ?director sc:name ?directorName .
    # ?film sc:name ?filmName .
    # ?academyAward sc:name ?academyAwardName .
    filter (?director=wd:Q25089 || ?director=wd:Q3772)
}
group by ?film ?filmName ?director ?directorName
LIMIT 50

"""
print("Results")
x=run_query(queryString)
# Out:
# Results
# [('director', 'http://www.wikidata.org/entity/Q3772'), ('directorName', 'Quentin Tarantino'), ('film', 'http://www.wikidata.org/entity/Q47300912'), ('filmName', 'Once Upon a Time in Hollywood'), ('totalAwards', '2')]
# [('director', 'http://www.wikidata.org/entity/Q25089'), ('directorName', 'Woody Allen'), ('film', 'http://www.wikidata.org/entity/Q845057'), ('filmName', 'Hannah and Her Sisters'), ('totalAwards', '3')]
# [('director', 'http://www.wikidata.org/entity/Q3772'), ('directorName', 'Quentin Tarantino'), ('film', 'http://www.wikidata.org/entity/Q153723'), ('filmName', 'Inglourious Basterds'), ('totalAwards', '1')]
# [('director', 'http://www.wikidata.org/entity/Q3772'), ('directorName', 'Quentin Tarantino'), ('film', 'http://www.wikidata.org/entity/Q104123'), ('filmName', 'Pulp Fiction'), ('totalAwards', '1')]
# [('director', 'http://www.wikidata.org/entity/Q3772'), ('directorName', 'Quentin Tarantino'), ('film', 'http://www.wikidata.org/entity/Q571032'), ('filmName', 'Django Unchained'), ('totalAwards', '2')]
# [('director', 'http://www.wikidata.org/entity/Q25089'), ('directorName', 'Woody Allen'), ('film', 'http://www.wikidata.org/entity/Q233464'), ('filmName', 'Annie Hall'), ('totalAwards', '4')]
# [('director', 'http://www.wikidata.org/entity/Q25089'), ('directorName', 'Woody Allen'), ('film', 'http://www.wikidata.org/entity/Q206124'), ('filmName', 'Midnight in Paris'), ('totalAwards', '1')]
# [('director', 'http://www.wikidata.org/entity/Q25089'), ('directorName', 'Woody Allen'), ('film', 'http://www.wikidata.org/entity/Q212123'), ('filmName', 'Vicky Cristina Barcelona'), ('totalAwards', '1')]
# [('director', 'http://www.wikidata.org/entity/Q25089'), ('directorName', 'Woody Allen'), ('film', 'http://www.wikidata.org/entity/Q2907178'), ('filmName', 'Blue Jasmine'), ('totalAwards', '1')]
# [('director', 'http://www.wikidata.org/entity/Q3772'), ('directorName', 'Quentin Tarantino'), ('film', 'http://www.wikidata.org/entity/Q18225084'), ('filmName', 'The Hateful Eight'), ('totalAwards', '1')]
# [('director', 'http://www.wikidata.org/entity/Q25089'), ('directorName', 'Woody Allen'), ('film', 'http://www.wikidata.org/entity/Q1354109'), ('filmName', 'Mighty Aphrodite'), ('totalAwards', '1')]
# [('director', 'http://www.wikidata.org/entity/Q25089'), ('directorName', 'Woody Allen'), ('film', 'http://www.wikidata.org/entity/Q1004531'), ('filmName', 'Bullets Over Broadway'), ('totalAwards', '1')]
# 12

# %%
# write your queries
# Academy Awards (Q19020)
# film (Q11424)
# award received (P166)
# director (P57)
# let's find academy awards won by films and also find director name
#group by director and film as well as count number of awards
# lets try to get maximum academy awards so we need MAX fun
queryString = """
SELECT DISTINCT ?director ?directorName (MAX(?totalAwards) as ?maxNoOfAwards)
WHERE{
SELECT DISTINCT ?director ?directorName ?film ?filmName (COUNT(?academyAward) as ?totalAwards)
WHERE {
    # ?academyAward wdt:P31 wd:Q19020 .
    # ?film wdt:P31 wd:Q11424;
        wdt:P57 ?director ;
        wdt:P166 ?academyAward .
        
    # ?director sc:name ?directorName .
    # ?film sc:name ?filmName .
    # ?academyAward sc:name ?academyAwardName .
    filter (?director=wd:Q25089 || ?director=wd:Q3772)
}
GROUP BY ?film ?filmName ?director ?directorName
}
group by ?film ?filmName ?director ?directorName
LIMIT 50

"""
print("Results")
x=run_query(queryString)
# Out:
# Results
# [('director', 'http://www.wikidata.org/entity/Q3772'), ('directorName', 'Quentin Tarantino'), ('maxNoOfAwards', '2')]
# [('director', 'http://www.wikidata.org/entity/Q25089'), ('directorName', 'Woody Allen'), ('maxNoOfAwards', '3')]
# [('director', 'http://www.wikidata.org/entity/Q3772'), ('directorName', 'Quentin Tarantino'), ('maxNoOfAwards', '1')]
# [('director', 'http://www.wikidata.org/entity/Q25089'), ('directorName', 'Woody Allen'), ('maxNoOfAwards', '4')]
# [('director', 'http://www.wikidata.org/entity/Q25089'), ('directorName', 'Woody Allen'), ('maxNoOfAwards', '1')]
# 5

# %%
# write your queries
# Academy Awards (Q19020)
# film (Q11424)
# award received (P166)
# director (P57)
# let's find academy awards won by films and also find director name
#group by director and film as well as count number of awards
# lets try to get maximum academy awards so we need MAX fun
queryString = """
SELECT DISTINCT ?director ?directorName (MAX(?totalAwards) as ?maxNoOfAwards)
WHERE{
SELECT DISTINCT ?director ?directorName ?film ?filmName (COUNT(?academyAward) as ?totalAwards)
WHERE {
    # ?academyAward wdt:P31 wd:Q19020 .
    # ?film wdt:P31 wd:Q11424;
        wdt:P57 ?director ;
        wdt:P166 ?academyAward .
        
    # ?director sc:name ?directorName .
    # ?film sc:name ?filmName .
    # ?academyAward sc:name ?academyAwardName .
    filter (?director=wd:Q25089 || ?director=wd:Q3772)
}
GROUP BY ?film ?filmName ?director ?directorName
}
group by ?director ?directorName
LIMIT 50

"""
print("Results")
x=run_query(queryString)
# Out:
# Results
# [('director', 'http://www.wikidata.org/entity/Q3772'), ('directorName', 'Quentin Tarantino'), ('maxNoOfAwards', '2')]
# [('director', 'http://www.wikidata.org/entity/Q25089'), ('directorName', 'Woody Allen'), ('maxNoOfAwards', '4')]
# 2

# %%
# write your queries
# Academy Awards (Q19020)
# film (Q11424)
# award received (P166)
# director (P57)
# let's find academy awards won by films and also find director name
#group by director and film as well as count number of awards
# lets try to get maximum academy awards so we need MAX fun
queryString = """
SELECT DISTINCT ?director ?directorName ?film ?filmName (MAX(?totalAwards) as ?maxNoOfAwards)
WHERE{
SELECT DISTINCT ?director ?directorName (COUNT(?academyAward) as ?totalAwards)
WHERE {
    # ?academyAward wdt:P31 wd:Q19020 .
    # ?film wdt:P31 wd:Q11424;
        wdt:P57 ?director ;
        wdt:P166 ?academyAward .
        
    # ?director sc:name ?directorName .
    # ?film sc:name ?filmName .
    #?academyAward sc:name ?academyAwardName .
    filter (?director=wd:Q25089 || ?director=wd:Q3772)
}
GROUP BY ?film ?filmName ?director ?directorName
}
group by ?director ?directorName ?film ?filmName
LIMIT 50

"""
print("Results")
x=run_query(queryString)
# Out:
# Results
# [('director', 'http://www.wikidata.org/entity/Q25089'), ('directorName', 'Woody Allen'), ('maxNoOfAwards', '4')]
# [('director', 'http://www.wikidata.org/entity/Q3772'), ('directorName', 'Quentin Tarantino'), ('maxNoOfAwards', '2')]
# 2

# %% [markdown]
# Final query for this task

# %%
# write your final query
# Academy Awards (Q19020)
# film (Q11424)
# award received (P166)
# director (P57)
# let's find academy awards won by films and also find director name
#group by director and film as well as count number of awards
# lets try to get maximum academy awards so we need MAX fun
queryString = """
SELECT DISTINCT ?director ?directorName ?film ?filmName (MAX(?totalAwards) as ?maxNoOfAwards)
WHERE{
SELECT DISTINCT ?director ?directorName (COUNT(?academyAward) as ?totalAwards)
WHERE {
    # ?academyAward wdt:P31 wd:Q19020 .
    # ?film wdt:P31 wd:Q11424;
        wdt:P57 ?director ;
        wdt:P166 ?academyAward .
        
    # ?director sc:name ?directorName .
    # ?film sc:name ?filmName .
    #?academyAward sc:name ?academyAwardName .
    filter (?director=wd:Q25089 || ?director=wd:Q3772)
}
GROUP BY ?film ?filmName ?director ?directorName
}
group by ?director ?directorName ?film ?filmName
LIMIT 50

"""
print("Results")
x=run_query(queryString)
# Out:
# Results
# [('director', 'http://www.wikidata.org/entity/Q25089'), ('directorName', 'Woody Allen'), ('maxNoOfAwards', '4')]
# [('director', 'http://www.wikidata.org/entity/Q3772'), ('directorName', 'Quentin Tarantino'), ('maxNoOfAwards', '2')]
# 2

# %% [markdown]
# ## Task 8
# Consider the set of films directed by Allen or Tarantino. Return for each Academy Award the total number of nomination of these films (the result set must be a list of triples Academy Award IRI, label and #nomination).

# %%
# write your queries
# Academy Awards (Q19020)
# film (Q11424)
# nominated for (P1411)
queryString = """
SELECT DISTINCT ?academyAward ?academyAwardName
WHERE {
# ?academyAward wdt:P31 wd:Q19020 .
# ?film wdt:P31 wd:Q11424;
    wdt:P57 ?director;
    wdt:P1411 ?academyAward.
   
# ?director sc:name ?directorName .
# ?academyAward sc:name ?academyAwardName
FILTER(?director=wd:Q25089 || ?director=wd:Q3772)
}
LIMIT 50
"""
print("Results")
x=run_query(queryString)
# Out:
# Results
# [('academyAward', 'http://www.wikidata.org/entity/Q102427'), ('academyAwardName', 'Academy Award for Best Picture')]
# [('academyAward', 'http://www.wikidata.org/entity/Q103360'), ('academyAwardName', 'Academy Award for Best Director')]
# [('academyAward', 'http://www.wikidata.org/entity/Q106301'), ('academyAwardName', 'Academy Award for Best Supporting Actress')]
# [('academyAward', 'http://www.wikidata.org/entity/Q281939'), ('academyAwardName', 'Academy Award for Best Film Editing')]
# [('academyAward', 'http://www.wikidata.org/entity/Q41417'), ('academyAwardName', 'Academy Award for Best Writing, Original Screenplay')]
# [('academyAward', 'http://www.wikidata.org/entity/Q103916'), ('academyAwardName', 'Academy Award for Best Actor')]
# [('academyAward', 'http://www.wikidata.org/entity/Q106291'), ('academyAwardName', 'Academy Award for Best Supporting Actor')]
# [('academyAward', 'http://www.wikidata.org/entity/Q131520'), ('academyAwardName', 'Academy Award for Best Cinematography')]
# [('academyAward', 'http://www.wikidata.org/entity/Q488645'), ('academyAwardName', 'Academy Award for Best Sound Editing')]
# [('academyAward', 'http://www.wikidata.org/entity/Q488651'), ('academyAwardName', 'Academy Award for Best Original Score')]
# [('academyAward', 'http://www.wikidata.org/entity/Q830079'), ('academyAwardName', 'Academy Award for Best Sound')]
# [('academyAward', 'http://www.wikidata.org/entity/Q103618'), ('academyAwardName', 'Academy Award for Best Actress')]
# [('academyAward', 'http://www.wikidata.org/entity/Q277536'), ('academyAwardName', 'Academy Award for Best Costume Design')]
# [('academyAward', 'http://www.wikidata.org/entity/Q277751'), ('academyAwardName', 'Academy Award for Best Production Design')]
# 14

# %%
# write your queries
# Academy Awards (Q19020)
# film (Q11424)
# nominated for (P1411) count its nomination for academy awards
queryString = """
SELECT DISTINCT ?academyAward ?academyAwardName (COUNT(?film) AS ?nominations)
WHERE {
# ?academyAward wdt:P31 wd:Q19020 .
# ?film wdt:P31 wd:Q11424;
    wdt:P57 ?director;
    wdt:P1411 ?academyAward.
   
# ?director sc:name ?directorName .
# ?academyAward sc:name ?academyAwardName
FILTER(?director=wd:Q25089 || ?director=wd:Q3772)
}
LIMIT 50
"""
print("Results")
x=run_query(queryString)
# Out:
# Results
# [('academyAward', 'http://www.wikidata.org/entity/Q277751'), ('academyAwardName', 'Academy Award for Best Production Design'), ('nominations', '5')]
# [('academyAward', 'http://www.wikidata.org/entity/Q281939'), ('academyAwardName', 'Academy Award for Best Film Editing'), ('nominations', '3')]
# [('academyAward', 'http://www.wikidata.org/entity/Q488651'), ('academyAwardName', 'Academy Award for Best Original Score'), ('nominations', '1')]
# [('academyAward', 'http://www.wikidata.org/entity/Q103618'), ('academyAwardName', 'Academy Award for Best Actress'), ('nominations', '3')]
# [('academyAward', 'http://www.wikidata.org/entity/Q103360'), ('academyAwardName', 'Academy Award for Best Director'), ('nominations', '9')]
# [('academyAward', 'http://www.wikidata.org/entity/Q106301'), ('academyAwardName', 'Academy Award for Best Supporting Actress'), ('nominations', '11')]
# [('academyAward', 'http://www.wikidata.org/entity/Q41417'), ('academyAwardName', 'Academy Award for Best Writing, Original Screenplay'), ('nominations', '19')]
# [('academyAward', 'http://www.wikidata.org/entity/Q488645'), ('academyAwardName', 'Academy Award for Best Sound Editing'), ('nominations', '2')]
# [('academyAward', 'http://www.wikidata.org/entity/Q131520'), ('academyAwardName', 'Academy Award for Best Cinematography'), ('nominations', '4')]
# [('academyAward', 'http://www.wikidata.org/entity/Q102427'), ('academyAwardName', 'Academy Award for Best Picture'), ('nominations', '6')]
# [('academyAward', 'http://www.wikidata.org/entity/Q103916'), ('academyAwardName', 'Academy Award for Best Actor'), ('nominations', '3')]
# [('academyAward', 'http://www.wikidata.org/entity/Q277536'), ('academyAwardName', 'Academy Award for Best Costume Design'), ('nominations', '2')]
# [('academyAward', 'http://www.wikidata.org/entity/Q106291'), ('academyAwardName', 'Academy Award for Best Supporting Actor'), ('nominations', '7')]
# [('academyAward', 'http://www.wikidata.org/entity/Q830079'), ('academyAwardName', 'Academy Award for Best Sound'), ('nominations', '1')]
# 14

# %%
# write your queries
# Academy Awards (Q19020)
# film (Q11424)
# nominated for (P1411) count its nomination for academy awards
# i was trying to find academy awards
queryString = """
SELECT DISTINCT ?academyAward ?academyAwardName (COUNT(?film) AS ?nominations)
WHERE {
# ?academyAward wdt:P31 wd:Q19020 .
# ?film wdt:P31 wd:Q11424;
    wdt:P57 ?director;
    wdt:P1411 ?academyAward.
   
# ?director sc:name ?directorName .
# ?academyAward sc:name ?academyAwardName
FILTER(?director=wd:Q25089 || ?director=wd:Q3772)
#filter (regex(?name, "Academy Awards"))
}
LIMIT 50
"""
print("Results")
x=run_query(queryString)
# Out:
# Results
# [('academyAward', 'http://www.wikidata.org/entity/Q277751'), ('academyAwardName', 'Academy Award for Best Production Design'), ('nominations', '5')]
# [('academyAward', 'http://www.wikidata.org/entity/Q281939'), ('academyAwardName', 'Academy Award for Best Film Editing'), ('nominations', '3')]
# [('academyAward', 'http://www.wikidata.org/entity/Q488651'), ('academyAwardName', 'Academy Award for Best Original Score'), ('nominations', '1')]
# [('academyAward', 'http://www.wikidata.org/entity/Q103618'), ('academyAwardName', 'Academy Award for Best Actress'), ('nominations', '3')]
# [('academyAward', 'http://www.wikidata.org/entity/Q103360'), ('academyAwardName', 'Academy Award for Best Director'), ('nominations', '9')]
# [('academyAward', 'http://www.wikidata.org/entity/Q106301'), ('academyAwardName', 'Academy Award for Best Supporting Actress'), ('nominations', '11')]
# [('academyAward', 'http://www.wikidata.org/entity/Q41417'), ('academyAwardName', 'Academy Award for Best Writing, Original Screenplay'), ('nominations', '19')]
# [('academyAward', 'http://www.wikidata.org/entity/Q488645'), ('academyAwardName', 'Academy Award for Best Sound Editing'), ('nominations', '2')]
# [('academyAward', 'http://www.wikidata.org/entity/Q131520'), ('academyAwardName', 'Academy Award for Best Cinematography'), ('nominations', '4')]
# [('academyAward', 'http://www.wikidata.org/entity/Q102427'), ('academyAwardName', 'Academy Award for Best Picture'), ('nominations', '6')]
# [('academyAward', 'http://www.wikidata.org/entity/Q103916'), ('academyAwardName', 'Academy Award for Best Actor'), ('nominations', '3')]
# [('academyAward', 'http://www.wikidata.org/entity/Q277536'), ('academyAwardName', 'Academy Award for Best Costume Design'), ('nominations', '2')]
# [('academyAward', 'http://www.wikidata.org/entity/Q106291'), ('academyAwardName', 'Academy Award for Best Supporting Actor'), ('nominations', '7')]
# [('academyAward', 'http://www.wikidata.org/entity/Q830079'), ('academyAwardName', 'Academy Award for Best Sound'), ('nominations', '1')]
# 14

# %% [markdown]
# Final query for this task

# %% [markdown]
# Final query for this task

# %%
# write your final query
# Academy Awards (Q19020)
# film (Q11424)
# nominated for (P1411) count its nomination for academy awards
queryString = """
SELECT DISTINCT ?academyAward ?academyAwardName (COUNT(?film) AS ?nominations)
WHERE {
# ?academyAward wdt:P31 wd:Q19020 .
# ?film wdt:P31 wd:Q11424;
    wdt:P57 ?director;
    wdt:P1411 ?academyAward.
   
# ?director sc:name ?directorName .
# ?academyAward sc:name ?academyAwardName
FILTER(?director=wd:Q25089 || ?director=wd:Q3772)
#filter (regex(?name, "Academy Awards"))
}
LIMIT 50
"""
print("Results")
x=run_query(queryString)
# Out:
# Results
# [('academyAward', 'http://www.wikidata.org/entity/Q277751'), ('academyAwardName', 'Academy Award for Best Production Design'), ('nominations', '5')]
# [('academyAward', 'http://www.wikidata.org/entity/Q281939'), ('academyAwardName', 'Academy Award for Best Film Editing'), ('nominations', '3')]
# [('academyAward', 'http://www.wikidata.org/entity/Q488651'), ('academyAwardName', 'Academy Award for Best Original Score'), ('nominations', '1')]
# [('academyAward', 'http://www.wikidata.org/entity/Q103618'), ('academyAwardName', 'Academy Award for Best Actress'), ('nominations', '3')]
# [('academyAward', 'http://www.wikidata.org/entity/Q103360'), ('academyAwardName', 'Academy Award for Best Director'), ('nominations', '9')]
# [('academyAward', 'http://www.wikidata.org/entity/Q106301'), ('academyAwardName', 'Academy Award for Best Supporting Actress'), ('nominations', '11')]
# [('academyAward', 'http://www.wikidata.org/entity/Q41417'), ('academyAwardName', 'Academy Award for Best Writing, Original Screenplay'), ('nominations', '19')]
# [('academyAward', 'http://www.wikidata.org/entity/Q488645'), ('academyAwardName', 'Academy Award for Best Sound Editing'), ('nominations', '2')]
# [('academyAward', 'http://www.wikidata.org/entity/Q131520'), ('academyAwardName', 'Academy Award for Best Cinematography'), ('nominations', '4')]
# [('academyAward', 'http://www.wikidata.org/entity/Q102427'), ('academyAwardName', 'Academy Award for Best Picture'), ('nominations', '6')]
# [('academyAward', 'http://www.wikidata.org/entity/Q103916'), ('academyAwardName', 'Academy Award for Best Actor'), ('nominations', '3')]
# [('academyAward', 'http://www.wikidata.org/entity/Q277536'), ('academyAwardName', 'Academy Award for Best Costume Design'), ('nominations', '2')]
# [('academyAward', 'http://www.wikidata.org/entity/Q106291'), ('academyAwardName', 'Academy Award for Best Supporting Actor'), ('nominations', '7')]
# [('academyAward', 'http://www.wikidata.org/entity/Q830079'), ('academyAwardName', 'Academy Award for Best Sound'), ('nominations', '1')]
# 14

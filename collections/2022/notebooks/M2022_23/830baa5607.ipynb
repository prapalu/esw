# %% [markdown]
# # General instructions
#
# The goal of the project is to materialize a set of **exploratory workloads** over a real-world, large-scale,  open-domain KG: [WikiData](https://www.wikidata.org/wiki/Wikidata:Main_Page)
#
# An exploratory workload  is composed by a set of queries, where each query is related to the information obtained previously.
#
# An exploratory workload starts with a usually vague, open ended question, and does not assume the person issuing the workload has a clear understanding of the data contained in the target database or its structure.
#
# Remeber that:
#
# 1. All the queries must run in the python notebook
# 2. You can use classes and properties only if you find them via a SPARQL query that must be present in the notebook
# 3. You do not delete useless queries. Keep everything that is synthatically valid
#
# ```
# ?p <http://schema.org/name> ?name .
# ```
#
#     is the BGP returning a human-readable name of a property or a class in Wikidata.

# %%
## SETUP used later

from SPARQLWrapper import SPARQLWrapper, JSON


prefixString = """
##-830baa5607-##
PREFIX wd: <http://www.wikidata.org/entity/> 
PREFIX wdt: <http://www.wikidata.org/prop/direct/> 
PREFIX sc: <http://schema.org/>
"""

# select and construct queries
def run_query(queryString,verbose = True):
    to_run = prefixString + "\n" + queryString

    sparql = SPARQLWrapper("http://a256-gc1-03.srv.aau.dk:5820/sparql")
    sparql.setTimeout(300)
    sparql.setReturnFormat(JSON)
    sparql.setQuery(to_run)

    try :
        results = sparql.query()
        json_results = results.convert()
        if len(json_results['results']['bindings'])==0:
            print("Empty")
            return []
        array = []
        for bindings in json_results['results']['bindings']:
            app =  [ (var, value['value'])  for var, value in bindings.items() ] 
            if verbose:
                print( app)
            array.append(app)
        if verbose:
            print(len(array))
        return array

    except Exception as e :
        print("The operation failed", e)
    
# ASk queries
def run_ask_query(queryString):
    to_run = prefixString + "\n" + queryString

    sparql = SPARQLWrapper("http://a256-gc1-03.srv.aau.dk:5820/sparql")
    sparql.setTimeout(300)
    sparql.setReturnFormat(JSON)
    sparql.setQuery(to_run)

    try :
        return sparql.query().convert()

    except Exception as e :
        print("The operation failed", e)

# %% [markdown]
# # Sport Workflow Series ("Running explorative search")
#
# Consider the following exploratory information need:
#
# > investigate the association football players and find the main BGPs related to this sports. Compare awards and participation in the competitions of the players

# %% [markdown]
# ## Useful URIs for the current workflow
# The following are given:
#
# | IRI           | Description   | Role      |
# | -----------   | -----------   |-----------|
# | `wdt:P1647`   | subproperty   | predicate |
# | `wdt:P31`     | instance of   | predicate |
# | `wdt:P106`    | profession    | predicate |
# | `wdt:P279`    | subclass      | predicate |
# | `wdt:P27`     | nationality   | predicate |
# | `wd:Q5`       | Human         | node      |
# | `wd:Q9124`    | Eliud Kipchoge| node      |
# | `wd:Q853003`| athletics at the 2008 Summer Olympics – men's 200 metres |node|

# %% [markdown]
# Also consider
#
# ```
# wd:Q9124 ?p ?obj .
# ```
#
# is the BGP to retrieve all **properties of Eliud Kipchoge**
#
#
# Please consider that when you return a resource, you should return the IRI and the label of the resource. In particular, when the task require you to identify a BGP the result set must always be a list of couples IRI - label.
#
#
# The workload should:
#
#
# 1. Identify the BGP for runner
#
# 2. Identify the BGP for long distance running
#
# 3. Return the disciplines of the long distance running (e.g. marathon) (the result set must be a list of couples discipline IRI and label).
#
# 4. Consider marathons ran in Europe. Return the number of different runners who won a marathon group by their country of citizenship (the result set must be a triples of country IRI, label and #different runners).
#
# 5. Identify the BGP for Olympic Games
#
# 6. Consider only the summer olympic games of 2004-2008-2012-2016. Return the number of marathon runners who had partecipated to all these editions group by their country of citizenship (if the runner partecipated in more than one edition of the game, consider him/her only once) (the result set must be a list of country IRI, label and #marathon runners)
#
# 7. For each disciplines of the long distance running find who hold the World Record (the result set must be a list of elements with discipline IRI, label and athlete IRI and label).

# %% [markdown]
# ## Task 1
# Identify the BGP for runner

# %%
# query example
queryString = """
SELECT DISTINCT ?p ?name
WHERE {
   # bind something
   wd:Q9124 ?p ?obj .
   # get the label
   # ?p sc:name ?name.
}
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P1000'), ('name', 'record held')]
# [('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('p', 'http://www.wikidata.org/prop/direct/P1146'), ('name', 'World Athletics athlete ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1344'), ('name', 'participant in')]
# [('p', 'http://www.wikidata.org/prop/direct/P1412'), ('name', 'languages spoken, written or signed')]
# [('p', 'http://www.wikidata.org/prop/direct/P1447'), ('name', 'Sports-Reference.com Olympic athlete ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1532'), ('name', 'country for sport')]
# [('p', 'http://www.wikidata.org/prop/direct/P1559'), ('name', 'name in native language')]
# [('p', 'http://www.wikidata.org/prop/direct/P172'), ('name', 'ethnic group')]
# [('p', 'http://www.wikidata.org/prop/direct/P1741'), ('name', 'GTAA ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P18'), ('name', 'image')]
# [('p', 'http://www.wikidata.org/prop/direct/P19'), ('name', 'place of birth')]
# [('p', 'http://www.wikidata.org/prop/direct/P2002'), ('name', 'Twitter username')]
# [('p', 'http://www.wikidata.org/prop/direct/P2003'), ('name', 'Instagram username')]
# [('p', 'http://www.wikidata.org/prop/direct/P2013'), ('name', 'Facebook ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2048'), ('name', 'height')]
# [('p', 'http://www.wikidata.org/prop/direct/P2067'), ('name', 'mass')]
# [('p', 'http://www.wikidata.org/prop/direct/P21'), ('name', 'sex or gender')]
# [('p', 'http://www.wikidata.org/prop/direct/P214'), ('name', 'VIAF ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P227'), ('name', 'GND ID')]
# 20

# %%
# aim: get all the properties of 'Eliud Kipchoge'
# result: we got all the resource properties. Now we can investigate both the properties 'sport' and 'occupation'
queryString = """
SELECT DISTINCT ?p ?name
WHERE {
   # bind something
   wd:Q9124 ?p ?obj .
   # get the label
   # ?p sc:name ?name.
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P1000'), ('name', 'record held')]
# [('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('p', 'http://www.wikidata.org/prop/direct/P1146'), ('name', 'World Athletics athlete ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1344'), ('name', 'participant in')]
# [('p', 'http://www.wikidata.org/prop/direct/P1412'), ('name', 'languages spoken, written or signed')]
# [('p', 'http://www.wikidata.org/prop/direct/P1447'), ('name', 'Sports-Reference.com Olympic athlete ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1532'), ('name', 'country for sport')]
# [('p', 'http://www.wikidata.org/prop/direct/P1559'), ('name', 'name in native language')]
# [('p', 'http://www.wikidata.org/prop/direct/P172'), ('name', 'ethnic group')]
# [('p', 'http://www.wikidata.org/prop/direct/P1741'), ('name', 'GTAA ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P18'), ('name', 'image')]
# [('p', 'http://www.wikidata.org/prop/direct/P19'), ('name', 'place of birth')]
# [('p', 'http://www.wikidata.org/prop/direct/P2002'), ('name', 'Twitter username')]
# [('p', 'http://www.wikidata.org/prop/direct/P2003'), ('name', 'Instagram username')]
# [('p', 'http://www.wikidata.org/prop/direct/P2013'), ('name', 'Facebook ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2048'), ('name', 'height')]
# [('p', 'http://www.wikidata.org/prop/direct/P2067'), ('name', 'mass')]
# [('p', 'http://www.wikidata.org/prop/direct/P21'), ('name', 'sex or gender')]
# [('p', 'http://www.wikidata.org/prop/direct/P214'), ('name', 'VIAF ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P227'), ('name', 'GND ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2416'), ('name', 'sports discipline competed in')]
# [('p', 'http://www.wikidata.org/prop/direct/P27'), ('name', 'country of citizenship')]
# [('p', 'http://www.wikidata.org/prop/direct/P286'), ('name', 'head coach')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('name', 'instance of')]
# [('p', 'http://www.wikidata.org/prop/direct/P3171'), ('name', 'Olympic.org athlete ID (archived version)')]
# [('p', 'http://www.wikidata.org/prop/direct/P3520'), ('name', 'databaseOlympics.com athlete ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P373'), ('name', 'Commons category')]
# [('p', 'http://www.wikidata.org/prop/direct/P3765'), ('name', 'All-Athletics.com ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3884'), ('name', 'Tilastopaja male athlete ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3923'), ('name', 'Diamond League athlete ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3925'), ('name', 'Track and Field Statistics male athlete ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P4548'), ('name', 'Commonwealth Games Federation athlete ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P569'), ('name', 'date of birth')]
# [('p', 'http://www.wikidata.org/prop/direct/P5815'), ('name', 'Olympics.com athlete ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P641'), ('name', 'sport')]
# [('p', 'http://www.wikidata.org/prop/direct/P646'), ('name', 'Freebase ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7293'), ('name', 'PLWABN ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P734'), ('name', 'family name')]
# [('p', 'http://www.wikidata.org/prop/direct/P735'), ('name', 'given name')]
# [('p', 'http://www.wikidata.org/prop/direct/P7859'), ('name', 'WorldCat Identities ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8286'), ('name', 'Olympedia people ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8687'), ('name', 'social media followers')]
# [('p', 'http://www.wikidata.org/prop/direct/P2415'), ('name', 'personal best')]
# 43

# %%
# aim: check the objects related to the property 'sport'
# result: we found the sport he played. Maybe he was a runner since running is part of 'athletics' as sport
queryString = """
SELECT DISTINCT ?obj ?name
WHERE {
   # bind something
   wd:Q9124 wdt:P641 ?obj .
   # get the label
   # ?obj sc:name ?name.
}
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('obj', 'http://www.wikidata.org/entity/Q542'), ('name', 'athletics')]
# 1

# %%
# aim: check the objects related to the property 'occupation'
# result: we found that he was a 'marathon runner'. We hope that the property 'subclass of' exists so that it might relate it to 'runner'
queryString = """
SELECT DISTINCT ?obj ?name
WHERE {
   # bind something
   wd:Q9124 wdt:P106 ?obj .
   # get the label
   # ?obj sc:name ?name.
}
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('obj', 'http://www.wikidata.org/entity/Q13382460'), ('name', 'marathon runner')]
# [('obj', 'http://www.wikidata.org/entity/Q11513337'), ('name', 'athletics competitor')]
# [('obj', 'http://www.wikidata.org/entity/Q4439155'), ('name', 'long-distance runner')]
# 3

# %%
# aim: check the properties related to the object 'marathon runner'
# result: we found the properties 'subclass of'. We need to explore it.
queryString = """
SELECT DISTINCT ?p ?name
WHERE {
   # bind something
   wd:Q13382460 ?p ?obj .
   # get the label
   # ?p sc:name ?name .
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('name', 'subclass of')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('name', 'instance of')]
# [('p', 'http://www.wikidata.org/prop/direct/P373'), ('name', 'Commons category')]
# [('p', 'http://www.wikidata.org/prop/direct/P425'), ('name', 'field of this occupation')]
# [('p', 'http://www.wikidata.org/prop/direct/P910'), ('name', "topic's main category")]
# 5

# %%
# aim: check the objects related to 'subclass of' of 'marathon runner'
# result: we found that it's a subclass of 'long-distance runner'
queryString = """
SELECT DISTINCT ?obj ?name
WHERE {
   # bind something
   wd:Q13382460 wdt:P279 ?obj .
   # get the label
   # ?obj sc:name ?name .
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('obj', 'http://www.wikidata.org/entity/Q4439155'), ('name', 'long-distance runner')]
# 1

# %% [markdown]
# Final query for this task

# %%
# aim: directly check the objects related to an eventual property 'subclass of' of 'long-distance runner'
# result: we found the 'runner' object!
queryString = """
SELECT DISTINCT ?obj ?name
WHERE {
   # bind something
   wd:Q4439155 wdt:P279 ?obj .
   # get the label
   # ?obj sc:name ?name .
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('obj', 'http://www.wikidata.org/entity/Q12803959'), ('name', 'runner')]
# 1

# %% [markdown]
# ## Task 2
# Identify the BGP for long distance running

# %%
# aim: get all the properties of 'runner'
# result: all the properties of 'runner'
queryString = """
SELECT DISTINCT ?p ?name
WHERE {
   # bind something
   wd:Q12803959 ?p ?obj .
   # get the label
   # ?p sc:name ?name .
}
LIMIT 200
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P1014'), ('name', 'Art & Architecture Thesaurus ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1036'), ('name', 'Dewey Decimal Classification')]
# [('p', 'http://www.wikidata.org/prop/direct/P1296'), ('name', 'Gran Enciclopèdia Catalana ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1889'), ('name', 'different from')]
# [('p', 'http://www.wikidata.org/prop/direct/P227'), ('name', 'GND ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2347'), ('name', 'YSO ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P244'), ('name', 'Library of Congress authority ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P268'), ('name', 'Bibliothèque nationale de France ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('name', 'subclass of')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('name', 'instance of')]
# [('p', 'http://www.wikidata.org/prop/direct/P373'), ('name', 'Commons category')]
# [('p', 'http://www.wikidata.org/prop/direct/P425'), ('name', 'field of this occupation')]
# [('p', 'http://www.wikidata.org/prop/direct/P8814'), ('name', 'WordNet 3.1 Synset ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P910'), ('name', "topic's main category")]
# 14

# %%
# aim: check if 'long-distance running' is a subclass of 'athletics'
# result: we found 'running'. Maybe 'long-distance running' is a subclass of 'running'
queryString = """
SELECT DISTINCT ?s ?name
WHERE {
   # bind something
   # ?s wdt:P279 wd:Q542 .
   # get the label
   # ?s sc:name ?name .
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('s', 'http://www.wikidata.org/entity/Q3312129'), ('name', 'track and field')]
# [('s', 'http://www.wikidata.org/entity/Q1757181'), ('name', 'para athletics')]
# [('s', 'http://www.wikidata.org/entity/Q56199072'), ('name', 'sprint')]
# [('s', 'http://www.wikidata.org/entity/Q10235779'), ('name', 'indoor athletics')]
# [('s', 'http://www.wikidata.org/entity/Q202391'), ('name', 'racewalking')]
# [('s', 'http://www.wikidata.org/entity/Q2093999'), ('name', 'trail running')]
# [('s', 'http://www.wikidata.org/entity/Q1934817'), ('name', 'road running')]
# [('s', 'http://www.wikidata.org/entity/Q3694569'), ('name', 'running')]
# [('s', 'http://www.wikidata.org/entity/Q20900741'), ('name', "women's athletics")]
# [('s', 'http://www.wikidata.org/entity/Q99463481'), ('name', "men's athletics")]
# [('s', 'http://www.wikidata.org/entity/Q1753702'), ('name', 'wheelchair athletics')]
# [('s', 'http://www.wikidata.org/entity/Q1548072'), ('name', 'Parelloop')]
# [('s', 'http://www.wikidata.org/entity/Q2997936'), ('name', 'Corrida de Houilles')]
# [('s', 'http://www.wikidata.org/entity/Q1538290'), ('name', 'altitude training')]
# [('s', 'http://www.wikidata.org/entity/Q1469740'), ('name', 'Schleuderballwurf')]
# 15

# %%
# aim: check if 'long-distance running' is a subclass of 'running'
# result: we didn't find it. Maybe instead we need to check some data regarding the object 'long-distance runner'
queryString = """
SELECT DISTINCT ?s ?name
WHERE {
   # bind something
   # ?s wdt:P279 wd:Q3694569 .
   # get the label
   # ?s sc:name ?name .
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('s', 'http://www.wikidata.org/entity/Q675770'), ('name', 'stadion')]
# [('s', 'http://www.wikidata.org/entity/Q3001473'), ('name', 'Barefoot running')]
# [('s', 'http://www.wikidata.org/entity/Q2167372'), ('name', 'mountain running')]
# [('s', 'http://www.wikidata.org/entity/Q27685564'), ('name', '20,000 m run')]
# 4

# %%
# aim: check if 'long-distance running' maybe is 'played' by the 'long-distance runner'
# result: we found the property 'practiced by' that could be useful
queryString = """
SELECT DISTINCT ?p ?name
WHERE {
   # bind something
   # ?s ?p wd:Q4439155 .
   # get the label
   # ?p sc:name ?name .
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('p', 'http://www.wikidata.org/prop/direct/P1889'), ('name', 'different from')]
# [('p', 'http://www.wikidata.org/prop/direct/P2416'), ('name', 'sports discipline competed in')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('name', 'subclass of')]
# [('p', 'http://www.wikidata.org/prop/direct/P301'), ('name', "category's main topic")]
# [('p', 'http://www.wikidata.org/prop/direct/P3095'), ('name', 'practiced by')]
# [('p', 'http://www.wikidata.org/prop/direct/P466'), ('name', 'occupant')]
# [('p', 'http://www.wikidata.org/prop/direct/P641'), ('name', 'sport')]
# [('p', 'http://www.wikidata.org/prop/direct/P971'), ('name', 'category combines topics')]
# 9

# %% [markdown]
# Final query for this task

# %%
# aim: check if 'long-distance running' is 'practiced by' the 'long-distance runner'
# result: we found 'long-distance running'!
queryString = """
SELECT DISTINCT ?s ?name
WHERE {
   # bind something
   # ?s wdt:P3095 wd:Q4439155 .
   # get the label
   # ?s sc:name ?name .
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('s', 'http://www.wikidata.org/entity/Q917206'), ('name', 'long-distance running')]
# [('s', 'http://www.wikidata.org/entity/Q1934817'), ('name', 'road running')]
# 2

# %% [markdown]
# ## Task 3
# Return the disciplines of the long distance running (e.g. marathon) (the result set must be a list of couples discipline IRI and label).

# %%
# aim: get all the properties related to 'long-distance running'
# result: we found some properties that can be useful such as 'part of', 'subclass of', 'sport' and 'sports discipline competed in'
queryString = """
SELECT DISTINCT ?p ?name
WHERE {
   # bind something
   # ?s ?p wd:Q917206 .
   # get the label
   # ?p sc:name ?name .
}
LIMIT 200
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('p', 'http://www.wikidata.org/prop/direct/P156'), ('name', 'followed by')]
# [('p', 'http://www.wikidata.org/prop/direct/P2416'), ('name', 'sports discipline competed in')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('name', 'subclass of')]
# [('p', 'http://www.wikidata.org/prop/direct/P301'), ('name', "category's main topic")]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('name', 'instance of')]
# [('p', 'http://www.wikidata.org/prop/direct/P361'), ('name', 'part of')]
# [('p', 'http://www.wikidata.org/prop/direct/P413'), ('name', 'position played on team / speciality')]
# [('p', 'http://www.wikidata.org/prop/direct/P425'), ('name', 'field of this occupation')]
# [('p', 'http://www.wikidata.org/prop/direct/P641'), ('name', 'sport')]
# [('p', 'http://www.wikidata.org/prop/direct/P921'), ('name', 'main subject')]
# 11

# %%
# aim: get the objects for 'part of', 'sport' and 'sports discipline competed in'
# result: we only returned people names, so 'sports discipline competed in' can be avoided
queryString = """
SELECT DISTINCT ?s ?name ?p
WHERE {
   # bind something
   # ?s ?p wd:Q917206 .
   # get the label
   # ?s sc:name ?name .
   FILTER (?p IN(wdt:P361,wdt:P2416,wdt:P279,wdt:P641))
}
LIMIT 200
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('s', 'http://www.wikidata.org/entity/Q26844379'), ('name', 'one-hour run'), ('p', 'http://www.wikidata.org/prop/direct/P279')]
# [('s', 'http://www.wikidata.org/entity/Q2815830'), ('name', '2 miles run'), ('p', 'http://www.wikidata.org/prop/direct/P279')]
# [('s', 'http://www.wikidata.org/entity/Q215677'), ('name', 'half marathon'), ('p', 'http://www.wikidata.org/prop/direct/P279')]
# [('s', 'http://www.wikidata.org/entity/Q310447'), ('name', 'Ville Ritola'), ('p', 'http://www.wikidata.org/prop/direct/P2416')]
# [('s', 'http://www.wikidata.org/entity/Q18655088'), ('name', '2014 Rotterdam Marathon'), ('p', 'http://www.wikidata.org/prop/direct/P641')]
# [('s', 'http://www.wikidata.org/entity/Q14912256'), ('name', 'Günter Wöller'), ('p', 'http://www.wikidata.org/prop/direct/P2416')]
# [('s', 'http://www.wikidata.org/entity/Q163892'), ('name', '10,000 metres'), ('p', 'http://www.wikidata.org/prop/direct/P279')]
# [('s', 'http://www.wikidata.org/entity/Q240500'), ('name', '5000 metres'), ('p', 'http://www.wikidata.org/prop/direct/P279')]
# [('s', 'http://www.wikidata.org/entity/Q40244'), ('name', 'marathon'), ('p', 'http://www.wikidata.org/prop/direct/P279')]
# [('s', 'http://www.wikidata.org/entity/Q2774730'), ('name', '10K run'), ('p', 'http://www.wikidata.org/prop/direct/P279')]
# [('s', 'http://www.wikidata.org/entity/Q28074111'), ('name', 'Christel Rogiers'), ('p', 'http://www.wikidata.org/prop/direct/P2416')]
# [('s', 'http://www.wikidata.org/entity/Q35309646'), ('name', 'Ignas Brasevičius'), ('p', 'http://www.wikidata.org/prop/direct/P2416')]
# [('s', 'http://www.wikidata.org/entity/Q29963964'), ('name', 'Krishna Bahadur Basnet'), ('p', 'http://www.wikidata.org/prop/direct/P2416')]
# [('s', 'http://www.wikidata.org/entity/Q29964020'), ('name', 'Hassan Karimou'), ('p', 'http://www.wikidata.org/prop/direct/P2416')]
# [('s', 'http://www.wikidata.org/entity/Q500050'), ('name', 'cross country running'), ('p', 'http://www.wikidata.org/prop/direct/P279')]
# [('s', 'http://www.wikidata.org/entity/Q225913'), ('name', 'Miruts Yifter'), ('p', 'http://www.wikidata.org/prop/direct/P2416')]
# [('s', 'http://www.wikidata.org/entity/Q26303'), ('name', 'ultramarathon'), ('p', 'http://www.wikidata.org/prop/direct/P279')]
# [('s', 'http://www.wikidata.org/entity/Q9171043'), ('name', '5K run'), ('p', 'http://www.wikidata.org/prop/direct/P361')]
# [('s', 'http://www.wikidata.org/entity/Q274531'), ('name', 'Maura Viceconte'), ('p', 'http://www.wikidata.org/prop/direct/P2416')]
# [('s', 'http://www.wikidata.org/entity/Q983623'), ('name', 'Mariano Haro'), ('p', 'http://www.wikidata.org/prop/direct/P2416')]
# [('s', 'http://www.wikidata.org/entity/Q5998'), ('name', 'Vivian Cheruiyot'), ('p', 'http://www.wikidata.org/prop/direct/P2416')]
# [('s', 'http://www.wikidata.org/entity/Q269409'), ('name', 'Murray Halberg'), ('p', 'http://www.wikidata.org/prop/direct/P641')]
# [('s', 'http://www.wikidata.org/entity/Q5936464'), ('name', 'Otto Larsen'), ('p', 'http://www.wikidata.org/prop/direct/P2416')]
# [('s', 'http://www.wikidata.org/entity/Q7352665'), ('name', 'Robin Millhouse'), ('p', 'http://www.wikidata.org/prop/direct/P641')]
# [('s', 'http://www.wikidata.org/entity/Q11478626'), ('name', 'Shinji Kawashima'), ('p', 'http://www.wikidata.org/prop/direct/P2416')]
# [('s', 'http://www.wikidata.org/entity/Q27824999'), ('name', 'Geoffrey Yegon'), ('p', 'http://www.wikidata.org/prop/direct/P2416')]
# [('s', 'http://www.wikidata.org/entity/Q27825781'), ('name', 'Eliud Ngetich'), ('p', 'http://www.wikidata.org/prop/direct/P2416')]
# [('s', 'http://www.wikidata.org/entity/Q29646625'), ('name', 'Myitung Naw'), ('p', 'http://www.wikidata.org/prop/direct/P2416')]
# [('s', 'http://www.wikidata.org/entity/Q42393780'), ('name', 'Robel Fsiha'), ('p', 'http://www.wikidata.org/prop/direct/P2416')]
# [('s', 'http://www.wikidata.org/entity/Q42911445'), ('name', 'Henri De Belder'), ('p', 'http://www.wikidata.org/prop/direct/P641')]
# [('s', 'http://www.wikidata.org/entity/Q5877'), ('name', 'Meseret Defar'), ('p', 'http://www.wikidata.org/prop/direct/P2416')]
# [('s', 'http://www.wikidata.org/entity/Q20736637'), ('name', 'Alisa Vainio'), ('p', 'http://www.wikidata.org/prop/direct/P2416')]
# [('s', 'http://www.wikidata.org/entity/Q29654376'), ('name', 'Gerhart Hecker'), ('p', 'http://www.wikidata.org/prop/direct/P2416')]
# [('s', 'http://www.wikidata.org/entity/Q29789364'), ('name', 'Mohamed Hadheb Hannachi'), ('p', 'http://www.wikidata.org/prop/direct/P2416')]
# [('s', 'http://www.wikidata.org/entity/Q29789409'), ('name', 'Nguyễn Văn Lý'), ('p', 'http://www.wikidata.org/prop/direct/P2416')]
# [('s', 'http://www.wikidata.org/entity/Q30077567'), ('name', 'João Carvalho'), ('p', 'http://www.wikidata.org/prop/direct/P2416')]
# [('s', 'http://www.wikidata.org/entity/Q30077635'), ('name', 'José Torres'), ('p', 'http://www.wikidata.org/prop/direct/P2416')]
# [('s', 'http://www.wikidata.org/entity/Q30078543'), ('name', 'Marco Condori'), ('p', 'http://www.wikidata.org/prop/direct/P2416')]
# [('s', 'http://www.wikidata.org/entity/Q40853621'), ('name', 'Irene van Lieshout'), ('p', 'http://www.wikidata.org/prop/direct/P641')]
# [('s', 'http://www.wikidata.org/entity/Q60827443'), ('name', 'Sardana Trofimova'), ('p', 'http://www.wikidata.org/prop/direct/P2416')]
# [('s', 'http://www.wikidata.org/entity/Q16618141'), ('name', 'Yomif Kejelcha'), ('p', 'http://www.wikidata.org/prop/direct/P2416')]
# [('s', 'http://www.wikidata.org/entity/Q29974717'), ('name', 'Inni Aboubacar'), ('p', 'http://www.wikidata.org/prop/direct/P2416')]
# [('s', 'http://www.wikidata.org/entity/Q29974727'), ('name', 'Benjamin Longiros'), ('p', 'http://www.wikidata.org/prop/direct/P2416')]
# [('s', 'http://www.wikidata.org/entity/Q30006091'), ('name', 'Alain Razahasoa'), ('p', 'http://www.wikidata.org/prop/direct/P2416')]
# [('s', 'http://www.wikidata.org/entity/Q30006144'), ('name', 'Myint Kan'), ('p', 'http://www.wikidata.org/prop/direct/P2416')]
# [('s', 'http://www.wikidata.org/entity/Q30007343'), ('name', 'Paul Kuété'), ('p', 'http://www.wikidata.org/prop/direct/P2416')]
# [('s', 'http://www.wikidata.org/entity/Q42343183'), ('name', 'Omar Hassan Omar'), ('p', 'http://www.wikidata.org/prop/direct/P2416')]
# [('s', 'http://www.wikidata.org/entity/Q42849808'), ('name', "Thomas O'Riordan"), ('p', 'http://www.wikidata.org/prop/direct/P2416')]
# [('s', 'http://www.wikidata.org/entity/Q56257975'), ('name', 'Jennen Mortier'), ('p', 'http://www.wikidata.org/prop/direct/P641')]
# [('s', 'http://www.wikidata.org/entity/Q61756921'), ('name', 'Lodkeo Inthakoumman'), ('p', 'http://www.wikidata.org/prop/direct/P2416')]
# [('s', 'http://www.wikidata.org/entity/Q21823285'), ('name', 'Jordi García González'), ('p', 'http://www.wikidata.org/prop/direct/P641')]
# [('s', 'http://www.wikidata.org/entity/Q71874734'), ('name', 'Deborah Schöneborn'), ('p', 'http://www.wikidata.org/prop/direct/P2416')]
# [('s', 'http://www.wikidata.org/entity/Q72503570'), ('name', 'Rabea Schöneborn'), ('p', 'http://www.wikidata.org/prop/direct/P2416')]
# [('s', 'http://www.wikidata.org/entity/Q24265525'), ('name', 'Yasemin Can'), ('p', 'http://www.wikidata.org/prop/direct/P2416')]
# [('s', 'http://www.wikidata.org/entity/Q42953427'), ('name', 'Cormac Finnerty'), ('p', 'http://www.wikidata.org/prop/direct/P2416')]
# [('s', 'http://www.wikidata.org/entity/Q67995447'), ('name', 'Eveliina Randelin'), ('p', 'http://www.wikidata.org/prop/direct/P641')]
# [('s', 'http://www.wikidata.org/entity/Q80196602'), ('name', 'Vincent Kipchumba'), ('p', 'http://www.wikidata.org/prop/direct/P2416')]
# [('s', 'http://www.wikidata.org/entity/Q59770543'), ('name', 'Frank Futselaar'), ('p', 'http://www.wikidata.org/prop/direct/P2416')]
# [('s', 'http://www.wikidata.org/entity/Q65229730'), ('name', 'Osvald Johansen'), ('p', 'http://www.wikidata.org/prop/direct/P2416')]
# [('s', 'http://www.wikidata.org/entity/Q96699425'), ('name', 'Okubay Tsegay'), ('p', 'http://www.wikidata.org/prop/direct/P2416')]
# [('s', 'http://www.wikidata.org/entity/Q100883799'), ('name', 'Simen Halle Haugen'), ('p', 'http://www.wikidata.org/prop/direct/P641')]
# [('s', 'http://www.wikidata.org/entity/Q107359179'), ('name', 'Cole Hocker'), ('p', 'http://www.wikidata.org/prop/direct/P641')]
# [('s', 'http://www.wikidata.org/entity/Q17634742'), ('name', '2014 New York City Marathon'), ('p', 'http://www.wikidata.org/prop/direct/P641')]
# [('s', 'http://www.wikidata.org/entity/Q692387'), ('name', 'Arne Gabius'), ('p', 'http://www.wikidata.org/prop/direct/P2416')]
# [('s', 'http://www.wikidata.org/entity/Q2311088'), ('name', 'Teresa Kidd'), ('p', 'http://www.wikidata.org/prop/direct/P2416')]
# [('s', 'http://www.wikidata.org/entity/Q88730281'), ('name', 'Hiroki Abe'), ('p', 'http://www.wikidata.org/prop/direct/P2416')]
# [('s', 'http://www.wikidata.org/entity/Q100981087'), ('name', 'Lina Kiriliuk'), ('p', 'http://www.wikidata.org/prop/direct/P2416')]
# [('s', 'http://www.wikidata.org/entity/Q10309716'), ('name', 'José João da Silva'), ('p', 'http://www.wikidata.org/prop/direct/P2416')]
# [('s', 'http://www.wikidata.org/entity/Q29789497'), ('name', 'Hedhili Ben Boubaker'), ('p', 'http://www.wikidata.org/prop/direct/P2416')]
# [('s', 'http://www.wikidata.org/entity/Q23902207'), ('name', "Emmanuel M'Pioh"), ('p', 'http://www.wikidata.org/prop/direct/P2416')]
# [('s', 'http://www.wikidata.org/entity/Q23902208'), ('name', 'Ismael Mahmoud Ghassab'), ('p', 'http://www.wikidata.org/prop/direct/P2416')]
# [('s', 'http://www.wikidata.org/entity/Q29855453'), ('name', 'Ezequiel Baeza'), ('p', 'http://www.wikidata.org/prop/direct/P2416')]
# [('s', 'http://www.wikidata.org/entity/Q29855602'), ('name', 'Anatoly Sukharkov'), ('p', 'http://www.wikidata.org/prop/direct/P2416')]
# [('s', 'http://www.wikidata.org/entity/Q29866779'), ('name', 'Ryu Man-hyong'), ('p', 'http://www.wikidata.org/prop/direct/P2416')]
# [('s', 'http://www.wikidata.org/entity/Q29885953'), ('name', 'Rafael Mora'), ('p', 'http://www.wikidata.org/prop/direct/P2416')]
# [('s', 'http://www.wikidata.org/entity/Q29916375'), ('name', 'Leodigard Martin'), ('p', 'http://www.wikidata.org/prop/direct/P2416')]
# [('s', 'http://www.wikidata.org/entity/Q29933343'), ('name', 'Ibrahim Al-Taher'), ('p', 'http://www.wikidata.org/prop/direct/P2416')]
# [('s', 'http://www.wikidata.org/entity/Q30078472'), ('name', 'Sarath Prasanna Gamage'), ('p', 'http://www.wikidata.org/prop/direct/P2416')]
# [('s', 'http://www.wikidata.org/entity/Q35308117'), ('name', 'Yohanes Ghebregergis'), ('p', 'http://www.wikidata.org/prop/direct/P2416')]
# [('s', 'http://www.wikidata.org/entity/Q85112292'), ('name', 'Jasmijn Lau'), ('p', 'http://www.wikidata.org/prop/direct/P2416')]
# [('s', 'http://www.wikidata.org/entity/Q97349458'), ('name', 'Joseph Tiophil Panga'), ('p', 'http://www.wikidata.org/prop/direct/P641')]
# [('s', 'http://www.wikidata.org/entity/Q97353337'), ('name', 'Ben Preisner'), ('p', 'http://www.wikidata.org/prop/direct/P641')]
# [('s', 'http://www.wikidata.org/entity/Q97999492'), ('name', 'Arnold Rogers'), ('p', 'http://www.wikidata.org/prop/direct/P2416')]
# [('s', 'http://www.wikidata.org/entity/Q6120994'), ('name', 'Santiago Manguán'), ('p', 'http://www.wikidata.org/prop/direct/P2416')]
# [('s', 'http://www.wikidata.org/entity/Q29295760'), ('name', 'Eddie Fitzgerald'), ('p', 'http://www.wikidata.org/prop/direct/P2416')]
# [('s', 'http://www.wikidata.org/entity/Q29642368'), ('name', 'Jaroslav Šourek'), ('p', 'http://www.wikidata.org/prop/direct/P2416')]
# [('s', 'http://www.wikidata.org/entity/Q97012688'), ('name', 'Ibrahim Ezzaydouni'), ('p', 'http://www.wikidata.org/prop/direct/P2416')]
# [('s', 'http://www.wikidata.org/entity/Q97102695'), ('name', 'Emily Hosker-Thornhill'), ('p', 'http://www.wikidata.org/prop/direct/P641')]
# [('s', 'http://www.wikidata.org/entity/Q97119842'), ('name', 'Jiksa Tolosa'), ('p', 'http://www.wikidata.org/prop/direct/P2416')]
# [('s', 'http://www.wikidata.org/entity/Q97123364'), ('name', 'Peter Glans'), ('p', 'http://www.wikidata.org/prop/direct/P641')]
# [('s', 'http://www.wikidata.org/entity/Q97443697'), ('name', 'Ryan Mphahlele'), ('p', 'http://www.wikidata.org/prop/direct/P641')]
# [('s', 'http://www.wikidata.org/entity/Q97459021'), ('name', 'Primien Manirafasha'), ('p', 'http://www.wikidata.org/prop/direct/P641')]
# [('s', 'http://www.wikidata.org/entity/Q102397397'), ('name', 'Patrick Martin'), ('p', 'http://www.wikidata.org/prop/direct/P641')]
# [('s', 'http://www.wikidata.org/entity/Q52589'), ('name', 'Emil Zátopek'), ('p', 'http://www.wikidata.org/prop/direct/P2416')]
# [('s', 'http://www.wikidata.org/entity/Q69635196'), ('name', 'Kohei Futaoka'), ('p', 'http://www.wikidata.org/prop/direct/P2416')]
# [('s', 'http://www.wikidata.org/entity/Q96739322'), ('name', 'Andrew Epperson'), ('p', 'http://www.wikidata.org/prop/direct/P2416')]
# [('s', 'http://www.wikidata.org/entity/Q96748043'), ('name', 'Rina Cjuro'), ('p', 'http://www.wikidata.org/prop/direct/P2416')]
# [('s', 'http://www.wikidata.org/entity/Q96755348'), ('name', 'Mathilde Sénéchal'), ('p', 'http://www.wikidata.org/prop/direct/P2416')]
# [('s', 'http://www.wikidata.org/entity/Q101053716'), ('name', 'Yeheniya Prokofyeva'), ('p', 'http://www.wikidata.org/prop/direct/P2416')]
# [('s', 'http://www.wikidata.org/entity/Q27839142'), ('name', 'Kennedy Kimutai'), ('p', 'http://www.wikidata.org/prop/direct/P2416')]
# [('s', 'http://www.wikidata.org/entity/Q62711807'), ('name', 'Joan Ramon Moya Garcia'), ('p', 'http://www.wikidata.org/prop/direct/P2416')]
# [('s', 'http://www.wikidata.org/entity/Q25160529'), ('name', 'Ben Debognies'), ('p', 'http://www.wikidata.org/prop/direct/P2416')]
# [('s', 'http://www.wikidata.org/entity/Q45320683'), ('name', 'Simon Debognies'), ('p', 'http://www.wikidata.org/prop/direct/P641')]
# [('s', 'http://www.wikidata.org/entity/Q97285537'), ('name', 'Maxwell Rotich'), ('p', 'http://www.wikidata.org/prop/direct/P641')]
# [('s', 'http://www.wikidata.org/entity/Q97290664'), ('name', 'Callan Moody'), ('p', 'http://www.wikidata.org/prop/direct/P641')]
# [('s', 'http://www.wikidata.org/entity/Q97291064'), ('name', 'Matt Baxter'), ('p', 'http://www.wikidata.org/prop/direct/P2416')]
# [('s', 'http://www.wikidata.org/entity/Q97301814'), ('name', 'Iven Moise'), ('p', 'http://www.wikidata.org/prop/direct/P641')]
# [('s', 'http://www.wikidata.org/entity/Q97303177'), ('name', 'Canisious Nyamutsita'), ('p', 'http://www.wikidata.org/prop/direct/P641')]
# [('s', 'http://www.wikidata.org/entity/Q2164200'), ('name', 'one hour run'), ('p', 'http://www.wikidata.org/prop/direct/P279')]
# [('s', 'http://www.wikidata.org/entity/Q722620'), ('name', 'Ismael Kirui'), ('p', 'http://www.wikidata.org/prop/direct/P2416')]
# [('s', 'http://www.wikidata.org/entity/Q73758'), ('name', 'Thomas Longosiwa'), ('p', 'http://www.wikidata.org/prop/direct/P2416')]
# [('s', 'http://www.wikidata.org/entity/Q711817'), ('name', 'Frederick Lorz'), ('p', 'http://www.wikidata.org/prop/direct/P2416')]
# [('s', 'http://www.wikidata.org/entity/Q4392324'), ('name', 'Allan Zachariasen'), ('p', 'http://www.wikidata.org/prop/direct/P641')]
# [('s', 'http://www.wikidata.org/entity/Q29733452'), ('name', 'Franjo Škrinjar'), ('p', 'http://www.wikidata.org/prop/direct/P2416')]
# [('s', 'http://www.wikidata.org/entity/Q29963919'), ('name', 'Naser Babapour'), ('p', 'http://www.wikidata.org/prop/direct/P2416')]
# [('s', 'http://www.wikidata.org/entity/Q29974570'), ('name', 'Vithanakande Samarasinghe'), ('p', 'http://www.wikidata.org/prop/direct/P2416')]
# [('s', 'http://www.wikidata.org/entity/Q29995884'), ('name', 'Mariana Ysrael'), ('p', 'http://www.wikidata.org/prop/direct/P2416')]
# [('s', 'http://www.wikidata.org/entity/Q30006143'), ('name', 'Mohamed Khamis Taher'), ('p', 'http://www.wikidata.org/prop/direct/P641')]
# [('s', 'http://www.wikidata.org/entity/Q14943896'), ('name', 'Yeorjia Abatzidou'), ('p', 'http://www.wikidata.org/prop/direct/P2416')]
# [('s', 'http://www.wikidata.org/entity/Q30099624'), ('name', 'Hafida Gadi'), ('p', 'http://www.wikidata.org/prop/direct/P2416')]
# [('s', 'http://www.wikidata.org/entity/Q30123005'), ('name', 'Željko Petrović'), ('p', 'http://www.wikidata.org/prop/direct/P2416')]
# [('s', 'http://www.wikidata.org/entity/Q63169520'), ('name', 'Cristina Nogué Bori'), ('p', 'http://www.wikidata.org/prop/direct/P2416')]
# [('s', 'http://www.wikidata.org/entity/Q44405848'), ('name', 'Mohamed Choumassi'), ('p', 'http://www.wikidata.org/prop/direct/P2416')]
# [('s', 'http://www.wikidata.org/entity/Q29997028'), ('name', 'Apollinarie Nyinawabéra'), ('p', 'http://www.wikidata.org/prop/direct/P2416')]
# [('s', 'http://www.wikidata.org/entity/Q39336745'), ('name', 'François Willems'), ('p', 'http://www.wikidata.org/prop/direct/P2416')]
# [('s', 'http://www.wikidata.org/entity/Q44081622'), ('name', 'Didier Bernard'), ('p', 'http://www.wikidata.org/prop/direct/P2416')]
# [('s', 'http://www.wikidata.org/entity/Q56305456'), ('name', 'The Big Half'), ('p', 'http://www.wikidata.org/prop/direct/P641')]
# [('s', 'http://www.wikidata.org/entity/Q19767716'), ('name', '15K run'), ('p', 'http://www.wikidata.org/prop/direct/P279')]
# [('s', 'http://www.wikidata.org/entity/Q11725842'), ('name', 'Jessica Coulson'), ('p', 'http://www.wikidata.org/prop/direct/P2416')]
# [('s', 'http://www.wikidata.org/entity/Q96749329'), ('name', 'Emily Brichacek'), ('p', 'http://www.wikidata.org/prop/direct/P2416')]
# [('s', 'http://www.wikidata.org/entity/Q96755892'), ('name', 'Angelina Tsere'), ('p', 'http://www.wikidata.org/prop/direct/P2416')]
# [('s', 'http://www.wikidata.org/entity/Q96756017'), ('name', 'Rudo Mhonderwa'), ('p', 'http://www.wikidata.org/prop/direct/P2416')]
# [('s', 'http://www.wikidata.org/entity/Q96756093'), ('name', 'Natalia Elisante Sulle'), ('p', 'http://www.wikidata.org/prop/direct/P2416')]
# [('s', 'http://www.wikidata.org/entity/Q42769552'), ('name', 'Karel Pacák'), ('p', 'http://www.wikidata.org/prop/direct/P2416')]
# [('s', 'http://www.wikidata.org/entity/Q43081668'), ('name', 'Ludvík Bombík'), ('p', 'http://www.wikidata.org/prop/direct/P2416')]
# [('s', 'http://www.wikidata.org/entity/Q97345961'), ('name', 'Edward Mwanza'), ('p', 'http://www.wikidata.org/prop/direct/P641')]
# [('s', 'http://www.wikidata.org/entity/Q97361537'), ('name', 'Yves Sikubwabo'), ('p', 'http://www.wikidata.org/prop/direct/P641')]
# [('s', 'http://www.wikidata.org/entity/Q97362067'), ('name', 'Sesebo Matlapeng'), ('p', 'http://www.wikidata.org/prop/direct/P641')]
# [('s', 'http://www.wikidata.org/entity/Q101678865'), ('name', 'Elena Adelina Panaet'), ('p', 'http://www.wikidata.org/prop/direct/P2416')]
# [('s', 'http://www.wikidata.org/entity/Q39073573'), ('name', 'Claire McCarthy'), ('p', 'http://www.wikidata.org/prop/direct/P2416')]
# [('s', 'http://www.wikidata.org/entity/Q94579936'), ('name', 'Leo Lehto'), ('p', 'http://www.wikidata.org/prop/direct/P641')]
# [('s', 'http://www.wikidata.org/entity/Q65549672'), ('name', 'Yūka Suzuki'), ('p', 'http://www.wikidata.org/prop/direct/P2416')]
# [('s', 'http://www.wikidata.org/entity/Q51159888'), ('name', 'Nick Van Peborgh'), ('p', 'http://www.wikidata.org/prop/direct/P2416')]
# [('s', 'http://www.wikidata.org/entity/Q62396413'), ('name', 'Xavier Fricaudet'), ('p', 'http://www.wikidata.org/prop/direct/P641')]
# [('s', 'http://www.wikidata.org/entity/Q2340625'), ('name', 'Koen Naert'), ('p', 'http://www.wikidata.org/prop/direct/P641')]
# [('s', 'http://www.wikidata.org/entity/Q101052818'), ('name', 'Katerine Tisalema'), ('p', 'http://www.wikidata.org/prop/direct/P2416')]
# [('s', 'http://www.wikidata.org/entity/Q101070084'), ('name', 'Nolene Conrad'), ('p', 'http://www.wikidata.org/prop/direct/P2416')]
# [('s', 'http://www.wikidata.org/entity/Q101074620'), ('name', 'Simon Holbek Kønigsfeldt'), ('p', 'http://www.wikidata.org/prop/direct/P2416')]
# [('s', 'http://www.wikidata.org/entity/Q5273017'), ('name', 'Dick Hooper'), ('p', 'http://www.wikidata.org/prop/direct/P2416')]
# [('s', 'http://www.wikidata.org/entity/Q96957349'), ('name', 'Amina Mohamed Mgoo'), ('p', 'http://www.wikidata.org/prop/direct/P641')]
# [('s', 'http://www.wikidata.org/entity/Q96959891'), ('name', 'Zenebu Fikadu'), ('p', 'http://www.wikidata.org/prop/direct/P641')]
# [('s', 'http://www.wikidata.org/entity/Q96959996'), ('name', 'Deborah Samum'), ('p', 'http://www.wikidata.org/prop/direct/P2416')]
# [('s', 'http://www.wikidata.org/entity/Q96977011'), ('name', 'Alberte Kjær Pedersen'), ('p', 'http://www.wikidata.org/prop/direct/P641')]
# [('s', 'http://www.wikidata.org/entity/Q24859474'), ('name', 'Yusuke Nishiyama'), ('p', 'http://www.wikidata.org/prop/direct/P641')]
# [('s', 'http://www.wikidata.org/entity/Q97072893'), ('name', 'Virginia Moloney'), ('p', 'http://www.wikidata.org/prop/direct/P641')]
# [('s', 'http://www.wikidata.org/entity/Q97124618'), ('name', 'Thabang Mosiako'), ('p', 'http://www.wikidata.org/prop/direct/P641')]
# [('s', 'http://www.wikidata.org/entity/Q97137186'), ('name', 'Mike Tate'), ('p', 'http://www.wikidata.org/prop/direct/P641')]
# [('s', 'http://www.wikidata.org/entity/Q97137741'), ('name', 'Rory Linkletter'), ('p', 'http://www.wikidata.org/prop/direct/P641')]
# [('s', 'http://www.wikidata.org/entity/Q97151742'), ('name', 'Rochelle Sceats-Basil'), ('p', 'http://www.wikidata.org/prop/direct/P641')]
# [('s', 'http://www.wikidata.org/entity/Q97464823'), ('name', 'Sami Jibril'), ('p', 'http://www.wikidata.org/prop/direct/P641')]
# [('s', 'http://www.wikidata.org/entity/Q27768163'), ('name', 'Ivy Kibet'), ('p', 'http://www.wikidata.org/prop/direct/P2416')]
# [('s', 'http://www.wikidata.org/entity/Q12301897'), ('name', 'Anni Lønstad'), ('p', 'http://www.wikidata.org/prop/direct/P641')]
# [('s', 'http://www.wikidata.org/entity/Q97278066'), ('name', 'Marco Monko'), ('p', 'http://www.wikidata.org/prop/direct/P641')]
# [('s', 'http://www.wikidata.org/entity/Q97285627'), ('name', 'Enyew Mekonnen'), ('p', 'http://www.wikidata.org/prop/direct/P641')]
# [('s', 'http://www.wikidata.org/entity/Q97965341'), ('name', 'Sergiu Ciobanu'), ('p', 'http://www.wikidata.org/prop/direct/P2416')]
# [('s', 'http://www.wikidata.org/entity/Q107210036'), ('name', 'Tom Erik Halvorsen'), ('p', 'http://www.wikidata.org/prop/direct/P641')]
# [('s', 'http://www.wikidata.org/entity/Q14269826'), ('name', 'Víctor Aravena'), ('p', 'http://www.wikidata.org/prop/direct/P2416')]
# [('s', 'http://www.wikidata.org/entity/Q22119270'), ('name', 'Yuta Takahashi'), ('p', 'http://www.wikidata.org/prop/direct/P2416')]
# [('s', 'http://www.wikidata.org/entity/Q96286642'), ('name', 'Laura Galván'), ('p', 'http://www.wikidata.org/prop/direct/P2416')]
# [('s', 'http://www.wikidata.org/entity/Q96625375'), ('name', 'Kelsey Bruce'), ('p', 'http://www.wikidata.org/prop/direct/P2416')]
# [('s', 'http://www.wikidata.org/entity/Q100980086'), ('name', 'Morris Munene Gachaga'), ('p', 'http://www.wikidata.org/prop/direct/P2416')]
# [('s', 'http://www.wikidata.org/entity/Q100997938'), ('name', 'Jean Marie Vianney Niyomukiza'), ('p', 'http://www.wikidata.org/prop/direct/P2416')]
# [('s', 'http://www.wikidata.org/entity/Q5017935'), ('name', 'Caitriona Jennings'), ('p', 'http://www.wikidata.org/prop/direct/P641')]
# [('s', 'http://www.wikidata.org/entity/Q5219206'), ('name', 'Daniela Cârlan'), ('p', 'http://www.wikidata.org/prop/direct/P2416')]
# [('s', 'http://www.wikidata.org/entity/Q96869717'), ('name', 'Julian Spence'), ('p', 'http://www.wikidata.org/prop/direct/P2416')]
# [('s', 'http://www.wikidata.org/entity/Q97060345'), ('name', 'Mema Tiango'), ('p', 'http://www.wikidata.org/prop/direct/P641')]
# [('s', 'http://www.wikidata.org/entity/Q55407762'), ('name', 'Nozomi Tanaka'), ('p', 'http://www.wikidata.org/prop/direct/P2416')]
# [('s', 'http://www.wikidata.org/entity/Q5596020'), ('name', 'Granollers Half Marathon'), ('p', 'http://www.wikidata.org/prop/direct/P641')]
# [('s', 'http://www.wikidata.org/entity/Q23902223'), ('name', 'Leda Díaz'), ('p', 'http://www.wikidata.org/prop/direct/P2416')]
# [('s', 'http://www.wikidata.org/entity/Q574716'), ('name', 'Yonas Kifle'), ('p', 'http://www.wikidata.org/prop/direct/P641')]
# [('s', 'http://www.wikidata.org/entity/Q96741592'), ('name', 'Natalia Hawthorn'), ('p', 'http://www.wikidata.org/prop/direct/P641')]
# [('s', 'http://www.wikidata.org/entity/Q96747755'), ('name', 'Amelia Quirk'), ('p', 'http://www.wikidata.org/prop/direct/P2416')]
# [('s', 'http://www.wikidata.org/entity/Q96748458'), ('name', 'Caitlin Adams'), ('p', 'http://www.wikidata.org/prop/direct/P2416')]
# [('s', 'http://www.wikidata.org/entity/Q96748585'), ('name', 'Claire Sumner'), ('p', 'http://www.wikidata.org/prop/direct/P2416')]
# [('s', 'http://www.wikidata.org/entity/Q96756974'), ('name', 'Kokob Tesfagabriel'), ('p', 'http://www.wikidata.org/prop/direct/P2416')]
# [('s', 'http://www.wikidata.org/entity/Q97143927'), ('name', 'Patrick Dever'), ('p', 'http://www.wikidata.org/prop/direct/P641')]
# [('s', 'http://www.wikidata.org/entity/Q726405'), ('name', 'Ashu Kasim'), ('p', 'http://www.wikidata.org/prop/direct/P2416')]
# [('s', 'http://www.wikidata.org/entity/Q47462314'), ('name', 'Gigathlon'), ('p', 'http://www.wikidata.org/prop/direct/P641')]
# [('s', 'http://www.wikidata.org/entity/Q1373276'), ('name', 'Martti Vainio'), ('p', 'http://www.wikidata.org/prop/direct/P2416')]
# [('s', 'http://www.wikidata.org/entity/Q974214'), ('name', 'Sergio Sánchez'), ('p', 'http://www.wikidata.org/prop/direct/P2416')]
# [('s', 'http://www.wikidata.org/entity/Q19798420'), ('name', '2015 Rotterdam Marathon'), ('p', 'http://www.wikidata.org/prop/direct/P641')]
# [('s', 'http://www.wikidata.org/entity/Q27649635'), ('name', 'Leen Van Brempt'), ('p', 'http://www.wikidata.org/prop/direct/P641')]
# [('s', 'http://www.wikidata.org/entity/Q9371961'), ('name', 'Wendy Brear'), ('p', 'http://www.wikidata.org/prop/direct/P2416')]
# [('s', 'http://www.wikidata.org/entity/Q1684249'), ('name', 'Javier Álvarez'), ('p', 'http://www.wikidata.org/prop/direct/P2416')]
# [('s', 'http://www.wikidata.org/entity/Q21936545'), ('name', 'María Luisa Ronquillo'), ('p', 'http://www.wikidata.org/prop/direct/P2416')]
# [('s', 'http://www.wikidata.org/entity/Q30077624'), ('name', 'Víctor Serrano'), ('p', 'http://www.wikidata.org/prop/direct/P2416')]
# [('s', 'http://www.wikidata.org/entity/Q26161232'), ('name', 'María Guadalupe Sánchez Magaña'), ('p', 'http://www.wikidata.org/prop/direct/P2416')]
# [('s', 'http://www.wikidata.org/entity/Q47035567'), ('name', 'Yann Schrub'), ('p', 'http://www.wikidata.org/prop/direct/P2416')]
# [('s', 'http://www.wikidata.org/entity/Q42723321'), ('name', 'Jozef Koščák'), ('p', 'http://www.wikidata.org/prop/direct/P2416')]
# [('s', 'http://www.wikidata.org/entity/Q56706965'), ('name', 'Clement Deflandre'), ('p', 'http://www.wikidata.org/prop/direct/P641')]
# 200

# %% [markdown]
# Final query for this task

# %%
# aim: get all the properties of 'part of' and 'subclass of'
# result: the disciplines for 'long-distance running'. We notice that '5k run' and '5000 metres' could be the same discipline (they relates to 'long-distance running' through different
#         properties). The same holds for '10,000 metres' and '10K run'
queryString = """
SELECT DISTINCT ?s ?name ?p
WHERE {
   # bind something
   # ?s ?p wd:Q917206 .
   # get the label
   # ?s sc:name ?name .
   FILTER (?p IN(wdt:P361,wdt:P279))
}
LIMIT 200
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('s', 'http://www.wikidata.org/entity/Q26844379'), ('name', 'one-hour run'), ('p', 'http://www.wikidata.org/prop/direct/P279')]
# [('s', 'http://www.wikidata.org/entity/Q2815830'), ('name', '2 miles run'), ('p', 'http://www.wikidata.org/prop/direct/P279')]
# [('s', 'http://www.wikidata.org/entity/Q215677'), ('name', 'half marathon'), ('p', 'http://www.wikidata.org/prop/direct/P279')]
# [('s', 'http://www.wikidata.org/entity/Q163892'), ('name', '10,000 metres'), ('p', 'http://www.wikidata.org/prop/direct/P279')]
# [('s', 'http://www.wikidata.org/entity/Q240500'), ('name', '5000 metres'), ('p', 'http://www.wikidata.org/prop/direct/P279')]
# [('s', 'http://www.wikidata.org/entity/Q40244'), ('name', 'marathon'), ('p', 'http://www.wikidata.org/prop/direct/P279')]
# [('s', 'http://www.wikidata.org/entity/Q2774730'), ('name', '10K run'), ('p', 'http://www.wikidata.org/prop/direct/P279')]
# [('s', 'http://www.wikidata.org/entity/Q500050'), ('name', 'cross country running'), ('p', 'http://www.wikidata.org/prop/direct/P279')]
# [('s', 'http://www.wikidata.org/entity/Q26303'), ('name', 'ultramarathon'), ('p', 'http://www.wikidata.org/prop/direct/P279')]
# [('s', 'http://www.wikidata.org/entity/Q9171043'), ('name', '5K run'), ('p', 'http://www.wikidata.org/prop/direct/P361')]
# [('s', 'http://www.wikidata.org/entity/Q2164200'), ('name', 'one hour run'), ('p', 'http://www.wikidata.org/prop/direct/P279')]
# [('s', 'http://www.wikidata.org/entity/Q19767716'), ('name', '15K run'), ('p', 'http://www.wikidata.org/prop/direct/P279')]
# [('s', 'http://www.wikidata.org/entity/Q19827858'), ('name', '20 kilometres'), ('p', 'http://www.wikidata.org/prop/direct/P279')]
# [('s', 'http://www.wikidata.org/entity/Q2538895'), ('name', 'Waffenlauf'), ('p', 'http://www.wikidata.org/prop/direct/P279')]
# 14

# %% [markdown]
# ## Task 4
# Consider marathons ran in Europe. Return the number of different runners who won a marathon group by their country of citizenship (the result set must be a triples of country IRI, label and #different runners).

# %%
# aim: get all the properties related to 'marathon' to find an 'instance of' or similar property
# result: we found the property 'instance of'
queryString = """
SELECT DISTINCT ?p ?name
WHERE {
   # bind something
   # ?s ?p wd:Q40244 .
   # get the label
   # ?p sc:name ?name .
}
LIMIT 200
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P101'), ('name', 'field of work')]
# [('p', 'http://www.wikidata.org/prop/direct/P1269'), ('name', 'facet of')]
# [('p', 'http://www.wikidata.org/prop/direct/P138'), ('name', 'named after')]
# [('p', 'http://www.wikidata.org/prop/direct/P155'), ('name', 'follows')]
# [('p', 'http://www.wikidata.org/prop/direct/P2094'), ('name', 'competition class')]
# [('p', 'http://www.wikidata.org/prop/direct/P2416'), ('name', 'sports discipline competed in')]
# [('p', 'http://www.wikidata.org/prop/direct/P2522'), ('name', 'victory')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('name', 'subclass of')]
# [('p', 'http://www.wikidata.org/prop/direct/P301'), ('name', "category's main topic")]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('name', 'instance of')]
# [('p', 'http://www.wikidata.org/prop/direct/P360'), ('name', 'is a list of')]
# [('p', 'http://www.wikidata.org/prop/direct/P413'), ('name', 'position played on team / speciality')]
# [('p', 'http://www.wikidata.org/prop/direct/P425'), ('name', 'field of this occupation')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('name', 'has part')]
# [('p', 'http://www.wikidata.org/prop/direct/P641'), ('name', 'sport')]
# [('p', 'http://www.wikidata.org/prop/direct/P921'), ('name', 'main subject')]
# [('p', 'http://www.wikidata.org/prop/direct/P971'), ('name', 'category combines topics')]
# 17

# %%
# aim: get all the objects that are 'instance of' the class 'marathon'
# result: we got all the marathons that have been done. Now we need to find the ones performed in Europe
queryString = """
SELECT DISTINCT ?s ?name ?p
WHERE {
   # bind something
   # ?s wdt:P31 wd:Q40244 .
   # get the label
   # ?s sc:name ?name .
}
LIMIT 200
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('s', 'http://www.wikidata.org/entity/Q17021963'), ('name', 'Niagara Falls International Marathon')]
# [('s', 'http://www.wikidata.org/entity/Q17051087'), ('name', 'Kaohsiung International Marathon')]
# [('s', 'http://www.wikidata.org/entity/Q4494720'), ('name', "1966 European Athletics Championships – men's marathon")]
# [('s', 'http://www.wikidata.org/entity/Q22073467'), ('name', 'Morgantown Marathon')]
# [('s', 'http://www.wikidata.org/entity/Q448958'), ('name', 'Hamburg Marathon')]
# [('s', 'http://www.wikidata.org/entity/Q596830'), ('name', 'Lake Biwa Marathon')]
# [('s', 'http://www.wikidata.org/entity/Q818638'), ('name', 'Beppu-Ōita Marathon')]
# [('s', 'http://www.wikidata.org/entity/Q1341108'), ('name', 'Rotterdam Marathon')]
# [('s', 'http://www.wikidata.org/entity/Q1473381'), ('name', 'Fukuoka International Marathon')]
# [('s', 'http://www.wikidata.org/entity/Q5091447'), ('name', 'Chennai Marathon')]
# [('s', 'http://www.wikidata.org/entity/Q1256376'), ('name', 'Milano City Marathon')]
# [('s', 'http://www.wikidata.org/entity/Q124715'), ('name', 'Chuncheon Marathon')]
# [('s', 'http://www.wikidata.org/entity/Q528634'), ('name', 'Frankfurt Marathon')]
# [('s', 'http://www.wikidata.org/entity/Q57933742'), ('name', '2018 Frankfurt Marathon')]
# [('s', 'http://www.wikidata.org/entity/Q1071285'), ('name', 'Paris Marathon')]
# [('s', 'http://www.wikidata.org/entity/Q5995281'), ('name', 'Santiago Marathon')]
# [('s', 'http://www.wikidata.org/entity/Q807910'), ('name', 'Barcelona Marathon')]
# [('s', 'http://www.wikidata.org/entity/Q19946825'), ('name', 'Chișinău Marathon')]
# [('s', 'http://www.wikidata.org/entity/Q997129'), ('name', 'Brussels Marathon')]
# [('s', 'http://www.wikidata.org/entity/Q752138'), ('name', 'New York City Marathon')]
# [('s', 'http://www.wikidata.org/entity/Q2029795'), ('name', "1987 World Championships in Athletics – Men's Marathon")]
# [('s', 'http://www.wikidata.org/entity/Q2031637'), ('name', 'Prague Marathon')]
# [('s', 'http://www.wikidata.org/entity/Q3702630'), ('name', "1995 World Championships in Athletics – men's marathon")]
# [('s', 'http://www.wikidata.org/entity/Q2629108'), ('name', 'Antwerp Marathon')]
# [('s', 'http://www.wikidata.org/entity/Q3702617'), ('name', "2003 World Championships in Athletics – Men's Marathon")]
# [('s', 'http://www.wikidata.org/entity/Q4682987'), ('name', 'Adirondack Marathon')]
# [('s', 'http://www.wikidata.org/entity/Q4822656'), ('name', 'Auroville Marathon')]
# [('s', 'http://www.wikidata.org/entity/Q5031268'), ('name', 'Canberra Marathon')]
# [('s', 'http://www.wikidata.org/entity/Q22080291'), ('name', 'Almaty Marathon')]
# [('s', 'http://www.wikidata.org/entity/Q24993287'), ('name', 'Stirling Scottish Marathon')]
# [('s', 'http://www.wikidata.org/entity/Q25057864'), ('name', 'Lagos Marathon')]
# [('s', 'http://www.wikidata.org/entity/Q25059015'), ('name', 'The Woodlands Marathon')]
# [('s', 'http://www.wikidata.org/entity/Q1645007'), ('name', 'Treviso Marathon')]
# [('s', 'http://www.wikidata.org/entity/Q2160555'), ('name', "Rock 'n' Roll San Diego Marathon")]
# [('s', 'http://www.wikidata.org/entity/Q484129'), ('name', 'Seoul International Marathon')]
# [('s', 'http://www.wikidata.org/entity/Q578794'), ('name', 'London Marathon')]
# [('s', 'http://www.wikidata.org/entity/Q3702472'), ('name', "1997 World Championships in Athletics – Men's Marathon")]
# [('s', 'http://www.wikidata.org/entity/Q3702768'), ('name', "1999 World Championships in Athletics – Men's Marathon")]
# [('s', 'http://www.wikidata.org/entity/Q4982646'), ('name', 'Bucharest Marathon')]
# [('s', 'http://www.wikidata.org/entity/Q837910'), ('name', 'Turin Marathon')]
# [('s', 'http://www.wikidata.org/entity/Q6728037'), ('name', 'Madison Marathon')]
# [('s', 'http://www.wikidata.org/entity/Q6861249'), ('name', 'Milton Keynes Marathon')]
# [('s', 'http://www.wikidata.org/entity/Q6867999'), ('name', 'Minneapolis Marathon')]
# [('s', 'http://www.wikidata.org/entity/Q7009256'), ('name', 'New Jersey Marathon')]
# [('s', 'http://www.wikidata.org/entity/Q7419230'), ('name', 'Santa Barbara International Marathon')]
# [('s', 'http://www.wikidata.org/entity/Q7989052'), ('name', 'Westlink M7 Cities Marathon')]
# [('s', 'http://www.wikidata.org/entity/Q815553'), ('name', 'Belgrade Marathon')]
# [('s', 'http://www.wikidata.org/entity/Q3229843'), ('name', "1958 European Athletics Championships – men's marathon")]
# [('s', 'http://www.wikidata.org/entity/Q16953783'), ('name', 'Brisbane Marathon')]
# [('s', 'http://www.wikidata.org/entity/Q16970842'), ('name', 'Melbourne Marathon')]
# [('s', 'http://www.wikidata.org/entity/Q18344089'), ('name', 'Carver Wolverhampton City Marathon')]
# [('s', 'http://www.wikidata.org/entity/Q18405099'), ('name', 'Moscow Marathon')]
# [('s', 'http://www.wikidata.org/entity/Q814845'), ('name', 'Beirut Marathon')]
# [('s', 'http://www.wikidata.org/entity/Q1299639'), ('name', 'Seenlandmarathon')]
# [('s', 'http://www.wikidata.org/entity/Q1543025'), ('name', "Grandma's Marathon")]
# [('s', 'http://www.wikidata.org/entity/Q2537624'), ('name', '1998 European Athletics Championships – Marathon')]
# [('s', 'http://www.wikidata.org/entity/Q4481862'), ('name', "1978 European Athletics Championships – men's marathon")]
# [('s', 'http://www.wikidata.org/entity/Q4852886'), ('name', 'Baltimore Marathon')]
# [('s', 'http://www.wikidata.org/entity/Q21714423'), ('name', 'Jakarta Marathon')]
# [('s', 'http://www.wikidata.org/entity/Q22097676'), ('name', 'Chesterfield Marathon')]
# [('s', 'http://www.wikidata.org/entity/Q6722706'), ('name', 'Macau Marathon')]
# [('s', 'http://www.wikidata.org/entity/Q1187515'), ('name', 'Dubai Marathon')]
# [('s', 'http://www.wikidata.org/entity/Q748757'), ('name', 'Rome Marathon')]
# [('s', 'http://www.wikidata.org/entity/Q5435109'), ('name', 'Fargo Marathon')]
# [('s', 'http://www.wikidata.org/entity/Q6921811'), ('name', 'Mount Lemmon Marathon')]
# [('s', 'http://www.wikidata.org/entity/Q7081789'), ('name', 'Okanagan International Marathon')]
# [('s', 'http://www.wikidata.org/entity/Q7646150'), ('name', 'Surfside Beach Marathon')]
# [('s', 'http://www.wikidata.org/entity/Q18433381'), ('name', '2002 European Athletics Championships – Marathon')]
# [('s', 'http://www.wikidata.org/entity/Q731526'), ('name', 'Florence Marathon')]
# [('s', 'http://www.wikidata.org/entity/Q22000395'), ('name', 'Bournemouth Marathon')]
# [('s', 'http://www.wikidata.org/entity/Q48808331'), ('name', 'New Taipei City Wan Jin Shi Marathon')]
# [('s', 'http://www.wikidata.org/entity/Q28224520'), ('name', 'Maui Marathon')]
# [('s', 'http://www.wikidata.org/entity/Q55217414'), ('name', 'Hakodate Marathon')]
# [('s', 'http://www.wikidata.org/entity/Q48989165'), ('name', 'Uganda Marathon')]
# [('s', 'http://www.wikidata.org/entity/Q1902469'), ('name', 'Marrakech Marathon')]
# [('s', 'http://www.wikidata.org/entity/Q67105178'), ('name', 'Samara International Marathon')]
# [('s', 'http://www.wikidata.org/entity/Q1136968'), ('name', 'Vilnius Marathon')]
# [('s', 'http://www.wikidata.org/entity/Q1571297'), ('name', 'Porto Marathon')]
# [('s', 'http://www.wikidata.org/entity/Q2275385'), ('name', 'Sevilla Marathon')]
# [('s', 'http://www.wikidata.org/entity/Q2276923'), ('name', 'Shanghai Marathon')]
# [('s', 'http://www.wikidata.org/entity/Q3287504'), ('name', 'Marathon du beaujolais')]
# [('s', 'http://www.wikidata.org/entity/Q1513658'), ('name', 'Xiamen International Marathon')]
# [('s', 'http://www.wikidata.org/entity/Q5210924'), ('name', 'Dalian International Marathon')]
# [('s', 'http://www.wikidata.org/entity/Q5595011'), ('name', 'Grand Rapids Marathon')]
# [('s', 'http://www.wikidata.org/entity/Q2116756'), ('name', 'Marathon van São Paulo')]
# [('s', 'http://www.wikidata.org/entity/Q60851124'), ('name', 'Kazan Marathon')]
# [('s', 'http://www.wikidata.org/entity/Q17209726'), ('name', 'Yokohama Marathon')]
# [('s', 'http://www.wikidata.org/entity/Q950560'), ('name', 'Singapore Marathon')]
# [('s', 'http://www.wikidata.org/entity/Q4561578'), ('name', '2007 World Championships in Athletics – Marathon')]
# [('s', 'http://www.wikidata.org/entity/Q5349576'), ('name', 'Ein Gedi race')]
# [('s', 'http://www.wikidata.org/entity/Q16251118'), ('name', 'Kansas City Marathon')]
# [('s', 'http://www.wikidata.org/entity/Q18390417'), ('name', 'Yorkshire Marathon')]
# [('s', 'http://www.wikidata.org/entity/Q28403832'), ('name', 'Myrtle Beach Marathon')]
# [('s', 'http://www.wikidata.org/entity/Q4483679'), ('name', 'Philadelphia Marathon')]
# [('s', 'http://www.wikidata.org/entity/Q5086082'), ('name', 'Charlotte Observer Marathon')]
# [('s', 'http://www.wikidata.org/entity/Q15982476'), ('name', 'Lahore Marathon')]
# [('s', 'http://www.wikidata.org/entity/Q4672824'), ('name', 'Accra Milo Marathon')]
# [('s', 'http://www.wikidata.org/entity/Q4882300'), ('name', 'Belfast Marathon')]
# [('s', 'http://www.wikidata.org/entity/Q7260107'), ('name', 'Pune International Marathon')]
# [('s', 'http://www.wikidata.org/entity/Q28961288'), ('name', "Rock 'n' Roll Liverpool Marathon & 1/2 Marathon")]
# [('s', 'http://www.wikidata.org/entity/Q4457905'), ('name', "1938 European Athletics Championships – men's marathon")]
# [('s', 'http://www.wikidata.org/entity/Q24062748'), ('name', 'Monumental Marathon')]
# [('s', 'http://www.wikidata.org/entity/Q24189678'), ('name', 'Sunshine Coast Marathon')]
# [('s', 'http://www.wikidata.org/entity/Q285099'), ('name', 'Athens Classic Marathon')]
# [('s', 'http://www.wikidata.org/entity/Q1735199'), ('name', 'Kassel Marathon')]
# [('s', 'http://www.wikidata.org/entity/Q2138627'), ('name', '2010 European Athletics Championships – Marathon')]
# [('s', 'http://www.wikidata.org/entity/Q4489931'), ('name', "1934 European Athletics Championships – men's marathon")]
# [('s', 'http://www.wikidata.org/entity/Q3702661'), ('name', "2001 World Championships in Athletics – Men's Marathon")]
# [('s', 'http://www.wikidata.org/entity/Q2073515'), ('name', '1982 European Athletics Championships – Marathon')]
# [('s', 'http://www.wikidata.org/entity/Q4372860'), ('name', 'Tel Aviv Marathon')]
# [('s', 'http://www.wikidata.org/entity/Q7686523'), ('name', 'Taroko Gorge International Marathon')]
# [('s', 'http://www.wikidata.org/entity/Q314794'), ('name', 'Cologne Marathon')]
# [('s', 'http://www.wikidata.org/entity/Q923389'), ('name', 'Košice Peace Marathon')]
# [('s', 'http://www.wikidata.org/entity/Q4641953'), ('name', "1971 European Athletics Championships – men's marathon")]
# [('s', 'http://www.wikidata.org/entity/Q2106551'), ('name', 'Potsdamer Schlössermarathon')]
# [('s', 'http://www.wikidata.org/entity/Q2388747'), ('name', 'Taipei International Marathon')]
# [('s', 'http://www.wikidata.org/entity/Q2378198'), ('name', '2006 European Athletics Championships – Marathon')]
# [('s', 'http://www.wikidata.org/entity/Q7105575'), ('name', 'Osaka Marathon')]
# [('s', 'http://www.wikidata.org/entity/Q176586'), ('name', 'Leipzig Marathon')]
# [('s', 'http://www.wikidata.org/entity/Q1783882'), ('name', 'Copenhagen Marathon')]
# [('s', 'http://www.wikidata.org/entity/Q2097800'), ('name', 'Pyongyang Marathon')]
# [('s', 'http://www.wikidata.org/entity/Q18433379'), ('name', '1986 European Athletics Championships – Marathon')]
# [('s', 'http://www.wikidata.org/entity/Q5179843'), ('name', 'Cowtown Marathon')]
# [('s', 'http://www.wikidata.org/entity/Q17228348'), ('name', 'Kumamoto Castle Marathon')]
# [('s', 'http://www.wikidata.org/entity/Q6441022'), ('name', 'KL Marathon')]
# [('s', 'http://www.wikidata.org/entity/Q6909449'), ('name', 'Moray Marathon')]
# [('s', 'http://www.wikidata.org/entity/Q7089432'), ('name', 'Omaha Marathon')]
# [('s', 'http://www.wikidata.org/entity/Q7121506'), ('name', 'Paavo Nurmi Marathon')]
# [('s', 'http://www.wikidata.org/entity/Q7606912'), ('name', 'Steinmetz Gaborone Marathon')]
# [('s', 'http://www.wikidata.org/entity/Q17198869'), ('name', 'Bay of Fundy International Marathon')]
# [('s', 'http://www.wikidata.org/entity/Q19899312'), ('name', 'Vadodara Marathon')]
# [('s', 'http://www.wikidata.org/entity/Q17064643'), ('name', 'Ponce Marathon')]
# [('s', 'http://www.wikidata.org/entity/Q17082255'), ('name', 'Patna Marathon')]
# [('s', 'http://www.wikidata.org/entity/Q56827091'), ('name', '21K Buenos Aires')]
# [('s', 'http://www.wikidata.org/entity/Q48534877'), ('name', 'Nicosia Marathon')]
# [('s', 'http://www.wikidata.org/entity/Q96483031'), ('name', 'Saltykovsky Marathon')]
# [('s', 'http://www.wikidata.org/entity/Q203716'), ('name', 'Daegu Marathon')]
# [('s', 'http://www.wikidata.org/entity/Q67102580'), ('name', 'Ufa International Marathon')]
# [('s', 'http://www.wikidata.org/entity/Q259023'), ('name', 'Tallinn Marathon')]
# [('s', 'http://www.wikidata.org/entity/Q5278216'), ('name', 'Dingle Marathon')]
# [('s', 'http://www.wikidata.org/entity/Q879268'), ('name', 'Hannover Marathon')]
# [('s', 'http://www.wikidata.org/entity/Q1604568'), ('name', 'Helsinki City Marathon')]
# [('s', 'http://www.wikidata.org/entity/Q6672705'), ('name', 'Long Island Marathon')]
# [('s', 'http://www.wikidata.org/entity/Q6764107'), ('name', 'Marine Corps Marathon')]
# [('s', 'http://www.wikidata.org/entity/Q7902516'), ('name', 'Utah Valley Marathon')]
# [('s', 'http://www.wikidata.org/entity/Q13077264'), ('name', 'Palestine Marathon')]
# [('s', 'http://www.wikidata.org/entity/Q16981378'), ('name', 'Fredericton Marathon')]
# [('s', 'http://www.wikidata.org/entity/Q19891597'), ('name', 'Goa Marathon')]
# [('s', 'http://www.wikidata.org/entity/Q1029260'), ('name', 'Vancouver Marathon')]
# [('s', 'http://www.wikidata.org/entity/Q1266205'), ('name', 'Rhein-Ruhr-Marathon')]
# [('s', 'http://www.wikidata.org/entity/Q5038442'), ('name', 'Cardiff Marathon')]
# [('s', 'http://www.wikidata.org/entity/Q5038823'), ('name', "1954 European Athletics Championships – men's marathon")]
# [('s', 'http://www.wikidata.org/entity/Q1760313'), ('name', 'San Francisco Marathon')]
# [('s', 'http://www.wikidata.org/entity/Q3976256'), ('name', "1969 European Athletics Championships – men's marathon")]
# [('s', 'http://www.wikidata.org/entity/Q7319502'), ('name', 'Reykjavík Marathon')]
# [('s', 'http://www.wikidata.org/entity/Q7425590'), ('name', 'Saskatchewan Marathon')]
# [('s', 'http://www.wikidata.org/entity/Q7599767'), ('name', 'Stanley Marathon')]
# [('s', 'http://www.wikidata.org/entity/Q7830298'), ('name', 'Towpath Marathon')]
# [('s', 'http://www.wikidata.org/entity/Q7944460'), ('name', 'Växjö Marathon')]
# [('s', 'http://www.wikidata.org/entity/Q7971574'), ('name', "Washington's Birthday Marathon")]
# [('s', 'http://www.wikidata.org/entity/Q7983818'), ('name', 'Weskus Marathon')]
# [('s', 'http://www.wikidata.org/entity/Q11767307'), ('name', 'Wyszehrad Marathon')]
# [('s', 'http://www.wikidata.org/entity/Q17018163'), ('name', 'Maine Marathon')]
# [('s', 'http://www.wikidata.org/entity/Q4327940'), ('name', "1962 European Athletics Championships – men's marathon")]
# [('s', 'http://www.wikidata.org/entity/Q2508141'), ('name', 'Valencia Marathon')]
# [('s', 'http://www.wikidata.org/entity/Q246920'), ('name', 'Toronto Waterfront Marathon')]
# [('s', 'http://www.wikidata.org/entity/Q880287'), ('name', 'Düsseldorf Marathon')]
# [('s', 'http://www.wikidata.org/entity/Q1137231'), ('name', 'Country Music Marathon')]
# [('s', 'http://www.wikidata.org/entity/Q1169955'), ('name', 'Podgorica Marathon')]
# [('s', 'http://www.wikidata.org/entity/Q1187844'), ('name', 'Beijing Marathon')]
# [('s', 'http://www.wikidata.org/entity/Q302528'), ('name', 'Toronto Marathon')]
# [('s', 'http://www.wikidata.org/entity/Q1638105'), ('name', 'Cracovia Marathon')]
# [('s', 'http://www.wikidata.org/entity/Q1710748'), ('name', 'Porta-Marathon')]
# [('s', 'http://www.wikidata.org/entity/Q2245625'), ('name', 'Great Tibetan Marathon')]
# [('s', 'http://www.wikidata.org/entity/Q2247120'), ('name', '1990 European Athletics Championships – Marathon')]
# [('s', 'http://www.wikidata.org/entity/Q4816107'), ('name', 'Atlanta Marathon')]
# [('s', 'http://www.wikidata.org/entity/Q11589776'), ('name', 'Kobe Marathon')]
# [('s', 'http://www.wikidata.org/entity/Q24993179'), ('name', 'Birmingham International Marathon')]
# [('s', 'http://www.wikidata.org/entity/Q25055445'), ('name', 'Angkor Wat Marathons')]
# [('s', 'http://www.wikidata.org/entity/Q28225969'), ('name', 'Jaipur Marathon')]
# [('s', 'http://www.wikidata.org/entity/Q6536086'), ('name', 'Lewa Marathon')]
# [('s', 'http://www.wikidata.org/entity/Q6897051'), ('name', 'Mombasa Marathon')]
# [('s', 'http://www.wikidata.org/entity/Q6907430'), ('name', 'MoonWalk')]
# [('s', 'http://www.wikidata.org/entity/Q8021095'), ('name', 'Williams Route 66 Marathon')]
# [('s', 'http://www.wikidata.org/entity/Q15276908'), ('name', 'Polar Bear Marathon')]
# [('s', 'http://www.wikidata.org/entity/Q17109235'), ('name', 'Marathon by the Sea')]
# [('s', 'http://www.wikidata.org/entity/Q5498350'), ('name', 'Frederick Marathon')]
# [('s', 'http://www.wikidata.org/entity/Q5600641'), ('name', 'Greater Manchester Marathon')]
# [('s', 'http://www.wikidata.org/entity/Q6025033'), ('name', 'Indira Marathon')]
# [('s', 'http://www.wikidata.org/entity/Q6423680'), ('name', 'Knoxville Marathon')]
# [('s', 'http://www.wikidata.org/entity/Q25407763'), ('name', 'Maratón de la Comarca Lagunera')]
# [('s', 'http://www.wikidata.org/entity/Q24931168'), ('name', 'Ladakh Marathon')]
# [('s', 'http://www.wikidata.org/entity/Q24931408'), ('name', 'Hyderabad Marathon')]
# [('s', 'http://www.wikidata.org/entity/Q65272453'), ('name', 'Yodogawa Kanpei Marathon')]
# [('s', 'http://www.wikidata.org/entity/Q72971974'), ('name', '2019 New York City Marathon')]
# [('s', 'http://www.wikidata.org/entity/Q1943961'), ('name', 'Monaco Marathon')]
# [('s', 'http://www.wikidata.org/entity/Q1963862'), ('name', 'Nairobi Marathon')]
# [('s', 'http://www.wikidata.org/entity/Q4000583'), ('name', '2005 World Championships in Athletics – Marathon')]
# [('s', 'http://www.wikidata.org/entity/Q3917247'), ('name', "1950 European Athletics Championships – men's marathon")]
# [('s', 'http://www.wikidata.org/entity/Q17018883'), ('name', 'Miami Marathon')]
# 200

# %%
# aim: get all the properties of 'Milano City Marathon'
# result: we found the property 'country'
queryString = """
SELECT DISTINCT ?p ?name
WHERE {
   # bind something
   wd:Q1256376 ?p ?o.
   # get the label
   # ?p sc:name ?name .
}
LIMIT 200
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P17'), ('name', 'country')]
# [('p', 'http://www.wikidata.org/prop/direct/P18'), ('name', 'image')]
# [('p', 'http://www.wikidata.org/prop/direct/P2257'), ('name', 'event interval')]
# [('p', 'http://www.wikidata.org/prop/direct/P2397'), ('name', 'YouTube channel ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P276'), ('name', 'location')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('name', 'instance of')]
# [('p', 'http://www.wikidata.org/prop/direct/P373'), ('name', 'Commons category')]
# [('p', 'http://www.wikidata.org/prop/direct/P4794'), ('name', 'season starts')]
# [('p', 'http://www.wikidata.org/prop/direct/P571'), ('name', 'inception')]
# [('p', 'http://www.wikidata.org/prop/direct/P641'), ('name', 'sport')]
# [('p', 'http://www.wikidata.org/prop/direct/P646'), ('name', 'Freebase ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P856'), ('name', 'official website')]
# [('p', 'http://www.wikidata.org/prop/direct/P910'), ('name', "topic's main category")]
# 13

# %%
# aim: get the 'country' where the 'Milano City Marathon' was performed
# result: we found 'Italy' as expected
queryString = """
SELECT DISTINCT ?o ?name
WHERE {
   # bind something
   wd:Q1256376 wdt:P17 ?o .
   # get the label
   # ?o sc:name ?name .
}
LIMIT 5
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('o', 'http://www.wikidata.org/entity/Q38'), ('name', 'Italy')]
# 1

# %%
# aim: get all the properties of 'Italy'
# result: we found the 'continent' P30 property
queryString = """
SELECT DISTINCT ?p ?name
WHERE {
   # bind something
   wd:Q38 ?p ?o .
   # get the label
   # ?p sc:name ?name .
}
LIMIT 200
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P1005'), ('name', 'Portuguese National Library ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1036'), ('name', 'Dewey Decimal Classification')]
# [('p', 'http://www.wikidata.org/prop/direct/P1081'), ('name', 'Human Development Index')]
# [('p', 'http://www.wikidata.org/prop/direct/P1082'), ('name', 'population')]
# [('p', 'http://www.wikidata.org/prop/direct/P1120'), ('name', 'number of deaths')]
# [('p', 'http://www.wikidata.org/prop/direct/P1151'), ('name', "topic's main Wikimedia portal")]
# [('p', 'http://www.wikidata.org/prop/direct/P1198'), ('name', 'unemployment rate')]
# [('p', 'http://www.wikidata.org/prop/direct/P122'), ('name', 'basic form of government')]
# [('p', 'http://www.wikidata.org/prop/direct/P1225'), ('name', 'U.S. National Archives Identifier')]
# [('p', 'http://www.wikidata.org/prop/direct/P1245'), ('name', 'OmegaWiki Defined Meaning')]
# [('p', 'http://www.wikidata.org/prop/direct/P1296'), ('name', 'Gran Enciclopèdia Catalana ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1313'), ('name', 'office held by head of government')]
# [('p', 'http://www.wikidata.org/prop/direct/P1343'), ('name', 'described by source')]
# [('p', 'http://www.wikidata.org/prop/direct/P1365'), ('name', 'replaces')]
# [('p', 'http://www.wikidata.org/prop/direct/P1417'), ('name', 'Encyclopædia Britannica Online ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1419'), ('name', 'shape')]
# [('p', 'http://www.wikidata.org/prop/direct/P1438'), ('name', 'Jewish Encyclopedia ID (Russian)')]
# [('p', 'http://www.wikidata.org/prop/direct/P1451'), ('name', 'motto text')]
# [('p', 'http://www.wikidata.org/prop/direct/P1464'), ('name', 'category for people born here')]
# [('p', 'http://www.wikidata.org/prop/direct/P1465'), ('name', 'category for people who died here')]
# [('p', 'http://www.wikidata.org/prop/direct/P150'), ('name', 'contains administrative territorial entity')]
# [('p', 'http://www.wikidata.org/prop/direct/P1549'), ('name', 'demonym')]
# [('p', 'http://www.wikidata.org/prop/direct/P155'), ('name', 'follows')]
# [('p', 'http://www.wikidata.org/prop/direct/P1552'), ('name', 'has quality')]
# [('p', 'http://www.wikidata.org/prop/direct/P1566'), ('name', 'GeoNames ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1589'), ('name', 'lowest point')]
# [('p', 'http://www.wikidata.org/prop/direct/P1617'), ('name', 'BBC Things ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1622'), ('name', 'driving side')]
# [('p', 'http://www.wikidata.org/prop/direct/P163'), ('name', 'flag')]
# [('p', 'http://www.wikidata.org/prop/direct/P1667'), ('name', 'Getty Thesaurus of Geographic Names ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P17'), ('name', 'country')]
# [('p', 'http://www.wikidata.org/prop/direct/P1740'), ('name', 'category for films shot at this location')]
# [('p', 'http://www.wikidata.org/prop/direct/P1791'), ('name', 'category of people buried here')]
# [('p', 'http://www.wikidata.org/prop/direct/P1792'), ('name', 'category of associated people')]
# [('p', 'http://www.wikidata.org/prop/direct/P1842'), ('name', 'Global Anabaptist Mennonite Encyclopedia Online ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1906'), ('name', 'office held by head of state')]
# [('p', 'http://www.wikidata.org/prop/direct/P194'), ('name', 'legislative body')]
# [('p', 'http://www.wikidata.org/prop/direct/P2004'), ('name', 'NALT ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2046'), ('name', 'area')]
# [('p', 'http://www.wikidata.org/prop/direct/P206'), ('name', 'located in or next to body of water')]
# [('p', 'http://www.wikidata.org/prop/direct/P208'), ('name', 'executive body')]
# [('p', 'http://www.wikidata.org/prop/direct/P209'), ('name', 'highest judicial authority')]
# [('p', 'http://www.wikidata.org/prop/direct/P213'), ('name', 'ISNI')]
# [('p', 'http://www.wikidata.org/prop/direct/P214'), ('name', 'VIAF ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2163'), ('name', 'FAST ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2184'), ('name', 'history of topic')]
# [('p', 'http://www.wikidata.org/prop/direct/P2250'), ('name', 'life expectancy')]
# [('p', 'http://www.wikidata.org/prop/direct/P2258'), ('name', 'mobile country code')]
# [('p', 'http://www.wikidata.org/prop/direct/P227'), ('name', 'GND ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2347'), ('name', 'YSO ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P237'), ('name', 'coat of arms')]
# [('p', 'http://www.wikidata.org/prop/direct/P242'), ('name', 'locator map image')]
# [('p', 'http://www.wikidata.org/prop/direct/P244'), ('name', 'Library of Congress authority ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2573'), ('name', 'number of out-of-school children')]
# [('p', 'http://www.wikidata.org/prop/direct/P2581'), ('name', 'BabelNet ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2596'), ('name', 'culture')]
# [('p', 'http://www.wikidata.org/prop/direct/P2633'), ('name', 'geography of topic')]
# [('p', 'http://www.wikidata.org/prop/direct/P2852'), ('name', 'emergency telephone number')]
# [('p', 'http://www.wikidata.org/prop/direct/P2853'), ('name', 'electrical plug type')]
# [('p', 'http://www.wikidata.org/prop/direct/P2855'), ('name', 'VAT-rate')]
# [('p', 'http://www.wikidata.org/prop/direct/P2884'), ('name', 'mains voltage')]
# [('p', 'http://www.wikidata.org/prop/direct/P2924'), ('name', 'Great Russian Encyclopedia Online ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2936'), ('name', 'language used')]
# [('p', 'http://www.wikidata.org/prop/direct/P2950'), ('name', 'Nomisma ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2959'), ('name', 'permanent duplicated item')]
# [('p', 'http://www.wikidata.org/prop/direct/P297'), ('name', 'ISO 3166-1 alpha-2 code')]
# [('p', 'http://www.wikidata.org/prop/direct/P2979'), ('name', 'maritime identification digits')]
# [('p', 'http://www.wikidata.org/prop/direct/P298'), ('name', 'ISO 3166-1 alpha-3 code')]
# [('p', 'http://www.wikidata.org/prop/direct/P2981'), ('name', 'UIC alphabetical country code')]
# [('p', 'http://www.wikidata.org/prop/direct/P2982'), ('name', 'UIC numerical country code')]
# [('p', 'http://www.wikidata.org/prop/direct/P299'), ('name', 'ISO 3166-1 numeric code')]
# [('p', 'http://www.wikidata.org/prop/direct/P2997'), ('name', 'age of majority')]
# [('p', 'http://www.wikidata.org/prop/direct/P30'), ('name', 'continent')]
# [('p', 'http://www.wikidata.org/prop/direct/P3000'), ('name', 'marriageable age')]
# [('p', 'http://www.wikidata.org/prop/direct/P3024'), ('name', 'ITU letter code')]
# [('p', 'http://www.wikidata.org/prop/direct/P3067'), ('name', 'GS1 country code')]
# [('p', 'http://www.wikidata.org/prop/direct/P3068'), ('name', 'WIPO ST.3')]
# [('p', 'http://www.wikidata.org/prop/direct/P3097'), ('name', 'ISBN identifier group')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('name', 'instance of')]
# [('p', 'http://www.wikidata.org/prop/direct/P3106'), ('name', 'Guardian topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3175'), ('name', 'Statoids ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3219'), ('name', 'Encyclopædia Universalis ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3221'), ('name', 'New York Times topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3222'), ('name', 'NE.se ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3270'), ('name', 'compulsory education (minimum age)')]
# [('p', 'http://www.wikidata.org/prop/direct/P3271'), ('name', 'compulsory education (maximum age)')]
# [('p', 'http://www.wikidata.org/prop/direct/P3365'), ('name', 'Treccani ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3417'), ('name', 'Quora topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3422'), ('name', 'INSEE countries and foreign territories code')]
# [('p', 'http://www.wikidata.org/prop/direct/P3479'), ('name', 'Omni topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P349'), ('name', 'National Diet Library ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P35'), ('name', 'head of state')]
# [('p', 'http://www.wikidata.org/prop/direct/P3509'), ('name', 'Dagens Nyheter topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3529'), ('name', 'median income')]
# [('p', 'http://www.wikidata.org/prop/direct/P3553'), ('name', 'Zhihu topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P36'), ('name', 'capital')]
# [('p', 'http://www.wikidata.org/prop/direct/P361'), ('name', 'part of')]
# [('p', 'http://www.wikidata.org/prop/direct/P3612'), ('name', 'Le Monde diplomatique subject ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P37'), ('name', 'official language')]
# [('p', 'http://www.wikidata.org/prop/direct/P373'), ('name', 'Commons category')]
# [('p', 'http://www.wikidata.org/prop/direct/P3743'), ('name', 'ITU/ISO/IEC object identifier')]
# [('p', 'http://www.wikidata.org/prop/direct/P38'), ('name', 'currency')]
# [('p', 'http://www.wikidata.org/prop/direct/P3896'), ('name', 'geoshape')]
# [('p', 'http://www.wikidata.org/prop/direct/P3911'), ('name', 'STW Thesaurus for Economics ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3916'), ('name', 'UNESCO Thesaurus ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P395'), ('name', 'licence plate code')]
# [('p', 'http://www.wikidata.org/prop/direct/P3984'), ('name', 'subreddit')]
# [('p', 'http://www.wikidata.org/prop/direct/P3987'), ('name', 'SHARE Catalogue author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P402'), ('name', 'OpenStreetMap relation ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P4073'), ('name', 'Fandom wiki ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P41'), ('name', 'flag image')]
# [('p', 'http://www.wikidata.org/prop/direct/P417'), ('name', 'patron saint')]
# [('p', 'http://www.wikidata.org/prop/direct/P421'), ('name', 'located in time zone')]
# [('p', 'http://www.wikidata.org/prop/direct/P4342'), ('name', 'Store norske leksikon ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P4427'), ('name', 'GACS ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P443'), ('name', 'pronunciation audio')]
# [('p', 'http://www.wikidata.org/prop/direct/P4527'), ('name', 'UK Parliament thesaurus ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P4613'), ('name', 'Encyclopedia of Modern Ukraine ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P463'), ('name', 'member of')]
# [('p', 'http://www.wikidata.org/prop/direct/P4672'), ('name', 'EMLO location ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P47'), ('name', 'shares border with')]
# [('p', 'http://www.wikidata.org/prop/direct/P474'), ('name', 'country calling code')]
# [('p', 'http://www.wikidata.org/prop/direct/P4801'), ('name', 'LoC and MARC vocabularies ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P4841'), ('name', 'total fertility rate')]
# [('p', 'http://www.wikidata.org/prop/direct/P486'), ('name', 'MeSH descriptor ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P487'), ('name', 'Unicode character')]
# [('p', 'http://www.wikidata.org/prop/direct/P5002'), ('name', 'Orthodox Encyclopedia ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5008'), ('name', 'on focus list of Wikimedia project')]
# [('p', 'http://www.wikidata.org/prop/direct/P5019'), ('name', 'Brockhaus Enzyklopädie online ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5063'), ('name', 'Interlingual Index ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5125'), ('name', 'Wikimedia outline')]
# [('p', 'http://www.wikidata.org/prop/direct/P5180'), ('name', 'CIVICUS Monitor country entry')]
# [('p', 'http://www.wikidata.org/prop/direct/P5198'), ('name', 'ASC Leiden Thesaurus ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5247'), ('name', 'Giant Bomb ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5250'), ('name', 'IAB code')]
# [('p', 'http://www.wikidata.org/prop/direct/P530'), ('name', 'diplomatic relation')]
# [('p', 'http://www.wikidata.org/prop/direct/P5400'), ('name', 'GeoNLP ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5437'), ('name', 'EuroVoc ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5456'), ('name', 'TasteAtlas ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5573'), ('name', 'archINFORM location ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5658'), ('name', 'railway traffic side')]
# [('p', 'http://www.wikidata.org/prop/direct/P5698'), ('name', 'Invasive Species Compendium Datasheet ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P571'), ('name', 'inception')]
# [('p', 'http://www.wikidata.org/prop/direct/P5739'), ('name', 'Pontificia Università della Santa Croce ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5843'), ('name', 'Gynopedia ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5905'), ('name', 'Comic Vine ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6'), ('name', 'head of government')]
# [('p', 'http://www.wikidata.org/prop/direct/P605'), ('name', 'NUTS code')]
# [('p', 'http://www.wikidata.org/prop/direct/P610'), ('name', 'highest point')]
# [('p', 'http://www.wikidata.org/prop/direct/P6104'), ('name', 'maintained by WikiProject')]
# [('p', 'http://www.wikidata.org/prop/direct/P6150'), ('name', 'Academy Awards Database nominee ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6200'), ('name', 'BBC News topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6262'), ('name', 'Fandom article ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6293'), ('name', 'YSA ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6404'), ('name', "Treccani's Dizionario di Storia ID")]
# [('p', 'http://www.wikidata.org/prop/direct/P6413'), ('name', 'JORFSearch organization ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P646'), ('name', 'Freebase ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6573'), ('name', 'Klexikon article ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6592'), ('name', 'OpenStreetMap zoom level')]
# [('p', 'http://www.wikidata.org/prop/direct/P6766'), ('name', "Who's on First ID")]
# [('p', 'http://www.wikidata.org/prop/direct/P6839'), ('name', 'TV Tropes identifier')]
# [('p', 'http://www.wikidata.org/prop/direct/P6849'), ('name', 'DR topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P691'), ('name', 'NKCR AUT ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7012'), ('name', 'World Encyclopedia of Puppetry Arts ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P706'), ('name', 'located in/on physical feature')]
# [('p', 'http://www.wikidata.org/prop/direct/P7157'), ('name', 'The Top Tens ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7208'), ('name', 'Liber Liber author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7295'), ('name', 'Gregorian calendar start date')]
# [('p', 'http://www.wikidata.org/prop/direct/P7314'), ('name', 'TDV İslam Ansiklopedisi ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7322'), ('name', 'Marine Regions Geographic IDentifier (MRGID)')]
# [('p', 'http://www.wikidata.org/prop/direct/P7422'), ('name', 'minimum temperature record')]
# [('p', 'http://www.wikidata.org/prop/direct/P7471'), ('name', 'iNaturalist place ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P78'), ('name', 'top-level Internet domain')]
# [('p', 'http://www.wikidata.org/prop/direct/P7818'), ('name', 'French Vikidia ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7822'), ('name', 'Italian Vikidia ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7827'), ('name', 'Spanish Vikidia ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7829'), ('name', 'English Vikidia ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7832'), ('name', 'Basque Vikidia ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7850'), ('name', 'Joconde location ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7859'), ('name', 'WorldCat Identities ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7867'), ('name', 'category for maps')]
# [('p', 'http://www.wikidata.org/prop/direct/P7870'), ('name', 'Analysis & Policy Observatory term ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7960'), ('name', 'Joconde discovery ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7982'), ('name', 'Hrvatska enciklopedija ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8061'), ('name', 'AGROVOC ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8217'), ('name', 'iDAI.gazetteer ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8309'), ('name', 'Yle topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P832'), ('name', 'public holiday')]
# [('p', 'http://www.wikidata.org/prop/direct/P8349'), ('name', 'Proleksis enciklopedija ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8402'), ('name', 'open data portal')]
# [('p', 'http://www.wikidata.org/prop/direct/P8406'), ('name', 'Grove Art Online ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8408'), ('name', 'KBpedia ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8432'), ('name', 'Österreichisches Musiklexikon Online ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8472'), ('name', 'Encyclopedie berbere keyword ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P85'), ('name', 'anthem')]
# [('p', 'http://www.wikidata.org/prop/direct/P8519'), ('name', 'RKD thesaurus ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P856'), ('name', 'official website')]
# [('p', 'http://www.wikidata.org/prop/direct/P8744'), ('name', 'economy of topic')]
# [('p', 'http://www.wikidata.org/prop/direct/P8785'), ('name', 'AniDB tag ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8814'), ('name', 'WordNet 3.1 Synset ID')]
# 200

# %%
# aim: get all the properties of 'Italy'
# result: we found the 'continent' P30 property
queryString = """
SELECT DISTINCT ?o ?name
WHERE {
   # bind something
   wd:Q38 wdt:P30 ?o .
   # get the label
   # ?o sc:name ?name .
}
LIMIT 5
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('o', 'http://www.wikidata.org/entity/Q46'), ('name', 'Europe')]
# 1

# %%
# aim: get the marathons run in 'Europe'
# result: we found matarhons run in 'Europe'
queryString = """
SELECT DISTINCT ?europeanmarathon ?name
WHERE {
   # bind something
   # ?europeanmarathon ?p wd:Q40244 .
   # get the label
   # ?europeanmarathon wdt:P17 ?country .
   # ?country wdt:P30 wd:Q46 .
   # ?europeanmarathon sc:name ?name
}
LIMIT 200
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q161222'), ('name', 'Berlin Marathon')]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q528634'), ('name', 'Frankfurt Marathon')]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q1071285'), ('name', 'Paris Marathon')]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q679106'), ('name', 'Madrid Marathon')]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q807910'), ('name', 'Barcelona Marathon')]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q19946825'), ('name', 'Chișinău Marathon')]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q22080291'), ('name', 'Almaty Marathon')]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q24993287'), ('name', 'Stirling Scottish Marathon')]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q6861249'), ('name', 'Milton Keynes Marathon')]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q20894807'), ('name', '2015 Berlin Marathon')]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q18344089'), ('name', 'Carver Wolverhampton City Marathon')]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q22097676'), ('name', 'Chesterfield Marathon')]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q1136968'), ('name', 'Vilnius Marathon')]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q1571297'), ('name', 'Porto Marathon')]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q18390417'), ('name', 'Yorkshire Marathon')]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q85064458'), ('name', 'Avenue de Marathon - Marathonlaan')]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q4882300'), ('name', 'Belfast Marathon')]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q28961288'), ('name', "Rock 'n' Roll Liverpool Marathon & 1/2 Marathon")]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q6909449'), ('name', 'Moray Marathon')]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q7121506'), ('name', 'Paavo Nurmi Marathon')]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q55780710'), ('name', "2018 European Championships in Athletics – men's marathon")]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q5278216'), ('name', 'Dingle Marathon')]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q5038442'), ('name', 'Cardiff Marathon')]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q7319502'), ('name', 'Reykjavík Marathon')]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q7944460'), ('name', 'Växjö Marathon')]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q24993179'), ('name', 'Birmingham International Marathon')]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q6907430'), ('name', 'MoonWalk')]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q5600641'), ('name', 'Greater Manchester Marathon')]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q5445251'), ('name', 'Ferrara Marathon')]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q6658502'), ('name', 'Liverpool Marathon')]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q6664991'), ('name', 'Loch Ness Marathon')]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q21995538'), ('name', 'Bristol + Bath Marathon')]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q3287486'), ('name', 'Toulouse Marathon')]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q48741642'), ('name', 'Mersin Marathon')]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q7548598'), ('name', 'Snowdonia Marathon')]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q7797521'), ('name', 'Three Hearts Marathon')]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q6803429'), ('name', 'Meadows Marathon')]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q26235934'), ('name', 'Vitosha 100')]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q13488853'), ('name', 'Luxembourg Marathon')]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q7536292'), ('name', 'Skopje Marathon')]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q5626722'), ('name', 'Göteborg Marathon')]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q6380935'), ('name', 'Kazbegi Marathon')]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q7063668'), ('name', 'Nottingham Marathon')]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q4220213'), ('name', 'Kyiv Marathon')]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q4814257'), ('name', "athletics at the 1992 Summer Paralympics – men's marathon B1")]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q7912493'), ('name', 'Valmiera Marathon')]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q23845771'), ('name', 'Marathon for a Drug-Free Hungary')]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q7497355'), ('name', 'Shine')]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q6548901'), ('name', 'Limassol marathon')]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q7845398'), ('name', 'Midnight Sun Marathon')]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q12343891'), ('name', 'Viborg City Marathon')]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q16796287'), ('name', 'Empúries Marathon')]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q17496398'), ('name', "2014 European Athletics Championships – Women's Marathon")]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q4494720'), ('name', "1966 European Athletics Championships – men's marathon")]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q23308752'), ('name', 'Vienna City Marathon 1993')]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q23308753'), ('name', 'Vienna City Marathon 1994')]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q23308754'), ('name', 'Vienna City Marathon 1995')]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q448958'), ('name', 'Hamburg Marathon')]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q1187849'), ('name', 'Eindhoven Marathon')]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q1341108'), ('name', 'Rotterdam Marathon')]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q2271032'), ('name', 'Marathon Zeeuws-Vlaanderen')]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q3360287'), ('name', 'Marathon Brabant')]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q1256376'), ('name', 'Milano City Marathon')]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q248584'), ('name', 'Zürich Marathon')]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q1927089'), ('name', '2012 Berlin Marathon')]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q302355'), ('name', '2011 Berlin Marathon')]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q3026524'), ('name', '2010 Berlin Marathon')]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q1927506'), ('name', '1999 Paris Marathon')]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q1952434'), ('name', '2000 Paris Marathon')]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q2689716'), ('name', '1998 Paris Marathon')]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q478328'), ('name', 'Amsterdam Marathon')]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q13814181'), ('name', 'Vienna City Marathon 2012')]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q13814188'), ('name', 'Vienna City Marathon 2013')]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q20656439'), ('name', 'Vienna City Marathon 2014')]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q696031'), ('name', 'Vienna City Marathon')]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q20656463'), ('name', 'Vienna City Marathon 2005')]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q20667623'), ('name', 'Vienna City Marathon 2004')]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q20671660'), ('name', 'Vienna City Marathon 2002')]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q20677381'), ('name', 'Vienna City Marathon 2001')]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q23308760'), ('name', 'Vienna City Marathon 2000')]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q4543914'), ('name', 'Vienna City Marathon 2006')]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q14518765'), ('name', 'Westland Marathon')]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q20821373'), ('name', '1990 Westland Marathon')]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q20821376'), ('name', '1991 Westland Marathon')]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q997129'), ('name', 'Brussels Marathon')]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q857702'), ('name', 'Bienwald Marathon')]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q2026961'), ('name', '2003 Berlin Marathon')]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q2029795'), ('name', "1987 World Championships in Athletics – Men's Marathon")]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q2031637'), ('name', 'Prague Marathon')]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q2700241'), ('name', '2004 Berlin Marathon')]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q3466927'), ('name', '2002 Berlin Marathon')]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q3702630'), ('name', "1995 World Championships in Athletics – men's marathon")]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q479215'), ('name', 'Enschede Marathon')]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q13813340'), ('name', '2013 Rotterdam Marathon')]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q13814004'), ('name', '1997 Paris Marathon')]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q1967026'), ('name', '1990 Paris Marathon')]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q2540921'), ('name', '1993 Paris Marathon')]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q2629108'), ('name', 'Antwerp Marathon')]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q2694123'), ('name', '1992 Paris Marathon')]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q4588898'), ('name', '1993 World Marathon Cup')]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q4595298'), ('name', '1999 World Marathon Cup')]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q4602056'), ('name', '2003 World Marathon Cup')]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q4605105'), ('name', "2005 World Championships in Athletics – Men's Marathon")]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q4606142'), ('name', "2006 European Athletics Championships – Women's Marathon")]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q1980764'), ('name', 'Neujahrsmarathon Zürich')]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q30687990'), ('name', 'Breaking2')]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q1645007'), ('name', 'Treviso Marathon')]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q13813989'), ('name', '1987 Paris Marathon')]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q1814844'), ('name', '1989 Paris Marathon')]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q2133645'), ('name', '1988 Paris Marathon')]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q2483649'), ('name', '1991 London Marathon')]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q2509715'), ('name', '1993 London Marathon')]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q2649535'), ('name', '1992 London Marathon')]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q578794'), ('name', 'London Marathon')]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q3702768'), ('name', "1999 World Championships in Athletics – Men's Marathon")]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q4982646'), ('name', 'Bucharest Marathon')]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q837910'), ('name', 'Turin Marathon')]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q3229843'), ('name', "1958 European Athletics Championships – men's marathon")]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q15879074'), ('name', '2013 Berlin Marathon')]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q16823515'), ('name', '2014 Berlin Marathon')]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q18405099'), ('name', 'Moscow Marathon')]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q1299639'), ('name', 'Seenlandmarathon')]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q13813346'), ('name', '1975 Amsterdam Marathon')]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q20680130'), ('name', 'Frankfurt Marathon 1998')]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q2471649'), ('name', '1978 Berlin Marathon')]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q2483137'), ('name', '1977 Berlin Marathon')]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q3652508'), ('name', "1998 European Athletics Championships – Men's Marathon")]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q13814013'), ('name', '2004 Paris Marathon')]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q2551371'), ('name', '2002 Paris Marathon')]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q4488735'), ('name', '2003 Paris Marathon')]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q1247961'), ('name', 'Apeldoorn Marathon')]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q1258425'), ('name', 'Dresden Marathon')]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q748757'), ('name', 'Rome Marathon')]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q2045518'), ('name', '1975 Berlin Marathon')]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q2658328'), ('name', '1976 Berlin Marathon')]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q2856566'), ('name', '1974 Berlin Marathon')]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q13814019'), ('name', '2011 Paris Marathon')]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q13814026'), ('name', '2013 Paris Marathon')]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q2321989'), ('name', '2012 Paris Marathon')]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q15503324'), ('name', '1981 European Marathon Cup')]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q15505260'), ('name', '1983 European Marathon Cup')]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q731526'), ('name', 'Florence Marathon')]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q2490939'), ('name', '2010 Paris Marathon')]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q22000395'), ('name', 'Bournemouth Marathon')]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q27044204'), ('name', '2016 Berlin Marathon')]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q41537084'), ('name', '2017 Berlin Marathon')]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q67105178'), ('name', 'Samara International Marathon')]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q2718693'), ('name', '2009 London Marathon')]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q1863683'), ('name', '2012 London Marathon')]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q19776493'), ('name', '2015 London Marathon')]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q23905992'), ('name', '2016 London Marathon')]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q70636879'), ('name', 'INEOS 1:59 Challenge')]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q2275385'), ('name', 'Sevilla Marathon')]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q2572839'), ('name', '1999 London Marathon')]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q3287504'), ('name', 'Marathon du beaujolais')]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q1814000'), ('name', '1992 Amsterdam Marathon')]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q1926065'), ('name', '1979 Berlin Marathon')]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q2248738'), ('name', '2001 Paris Marathon')]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q2256373'), ('name', '1980 Berlin Marathon')]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q60851124'), ('name', 'Kazan Marathon')]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q23308733'), ('name', 'Vienna City Marathon 1984')]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q23308735'), ('name', 'Vienna City Marathon 1985')]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q29467338'), ('name', '2017 London Marathon')]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q4566093'), ('name', '1995 London Marathon')]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q4585982'), ('name', "1990 European Athletics Championships – Women's Marathon")]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q13814168'), ('name', 'Vienna City Marathon 2008')]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q13814173'), ('name', 'Vienna City Marathon 2009')]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q19838124'), ('name', '2013 Frankfurt Marathon')]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q20663238'), ('name', 'Vienna City Marathon 2010')]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q2355852'), ('name', '1983 Paris Marathon')]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q18816270'), ('name', 'The Hague Marathon')]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q1283094'), ('name', '2012 Olympic Marathon Course')]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q1891995'), ('name', '1994 Paris Marathon')]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q3089920'), ('name', '1995 Paris Marathon')]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q13813359'), ('name', '2005 Amsterdam Marathon')]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q2007515'), ('name', '2008 Paris Marathon')]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q2043084'), ('name', '2009 Paris Marathon')]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q2471208'), ('name', '2007 Paris Marathon')]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q4457905'), ('name', "1938 European Athletics Championships – men's marathon")]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q15883153'), ('name', 'Ultra Low Tide International Marathon')]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q19838127'), ('name', '2014 Hamburg Marathon')]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q20871344'), ('name', '2015 Hamburg Marathon')]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q19838125'), ('name', '2014 Frankfurt Marathon')]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q285099'), ('name', 'Athens Classic Marathon')]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q1735199'), ('name', 'Kassel Marathon')]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q1052426'), ('name', 'Utrecht Marathon')]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q2098319'), ('name', '1994 London Marathon')]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q13813352'), ('name', '2001 Amsterdam Marathon')]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q2244138'), ('name', 'Leeuwarden Marathon')]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q4489931'), ('name', "1934 European Athletics Championships – men's marathon")]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q1911222'), ('name', '2008 Berlin Marathon')]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q2385390'), ('name', '2009 Berlin Marathon')]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q1956719'), ('name', '1996 Berlin Marathon')]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q20732584'), ('name', '1980 Paris Marathon')]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q20735029'), ('name', '1982 Paris Marathon')]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q2266704'), ('name', '1998 Berlin Marathon')]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q2347383'), ('name', '2006 Paris Marathon')]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q2469199'), ('name', '1981 Paris Marathon')]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q2480440'), ('name', '1997 Berlin Marathon')]
# [('europeanmarathon', 'http://www.wikidata.org/entity/Q13813466'), ('name', '2006 Berlin Marathon')]
# 200

# %%
# aim: get all the properties related to '2006 Berlin Marathon'
# result: we didn't find interesting property but we noticed that '2006 Berlin Marathon' may related with 'instance of' to 'Berlin Marathon'
queryString = """
SELECT DISTINCT ?p1 ?name1 ?p2 ?name2
WHERE {
   # bind something
   # ?s ?p1 wd:Q13813466 .
   wd:Q13813466 ?p2 ?o.
   # get the label
   # ?p1 sc:name ?name1 .
   # ?p2 sc:name ?name2 .
}
LIMIT 200
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p1', 'http://www.wikidata.org/prop/direct/P155'), ('name1', 'follows'), ('p2', 'http://www.wikidata.org/prop/direct/P155'), ('name2', 'follows')]
# [('p1', 'http://www.wikidata.org/prop/direct/P156'), ('name1', 'followed by'), ('p2', 'http://www.wikidata.org/prop/direct/P155'), ('name2', 'follows')]
# [('p1', 'http://www.wikidata.org/prop/direct/P156'), ('name1', 'followed by'), ('p2', 'http://www.wikidata.org/prop/direct/P156'), ('name2', 'followed by')]
# [('p1', 'http://www.wikidata.org/prop/direct/P155'), ('name1', 'follows'), ('p2', 'http://www.wikidata.org/prop/direct/P156'), ('name2', 'followed by')]
# [('p1', 'http://www.wikidata.org/prop/direct/P155'), ('name1', 'follows'), ('p2', 'http://www.wikidata.org/prop/direct/P17'), ('name2', 'country')]
# [('p1', 'http://www.wikidata.org/prop/direct/P156'), ('name1', 'followed by'), ('p2', 'http://www.wikidata.org/prop/direct/P17'), ('name2', 'country')]
# [('p1', 'http://www.wikidata.org/prop/direct/P156'), ('name1', 'followed by'), ('p2', 'http://www.wikidata.org/prop/direct/P2671'), ('name2', 'Google Knowledge Graph ID')]
# [('p1', 'http://www.wikidata.org/prop/direct/P155'), ('name1', 'follows'), ('p2', 'http://www.wikidata.org/prop/direct/P2671'), ('name2', 'Google Knowledge Graph ID')]
# [('p1', 'http://www.wikidata.org/prop/direct/P155'), ('name1', 'follows'), ('p2', 'http://www.wikidata.org/prop/direct/P276'), ('name2', 'location')]
# [('p1', 'http://www.wikidata.org/prop/direct/P156'), ('name1', 'followed by'), ('p2', 'http://www.wikidata.org/prop/direct/P276'), ('name2', 'location')]
# [('p1', 'http://www.wikidata.org/prop/direct/P156'), ('name1', 'followed by'), ('p2', 'http://www.wikidata.org/prop/direct/P31'), ('name2', 'instance of')]
# [('p1', 'http://www.wikidata.org/prop/direct/P155'), ('name1', 'follows'), ('p2', 'http://www.wikidata.org/prop/direct/P31'), ('name2', 'instance of')]
# [('p1', 'http://www.wikidata.org/prop/direct/P155'), ('name1', 'follows'), ('p2', 'http://www.wikidata.org/prop/direct/P3450'), ('name2', 'sports season of league or competition')]
# [('p1', 'http://www.wikidata.org/prop/direct/P156'), ('name1', 'followed by'), ('p2', 'http://www.wikidata.org/prop/direct/P3450'), ('name2', 'sports season of league or competition')]
# [('p1', 'http://www.wikidata.org/prop/direct/P156'), ('name1', 'followed by'), ('p2', 'http://www.wikidata.org/prop/direct/P585'), ('name2', 'point in time')]
# [('p1', 'http://www.wikidata.org/prop/direct/P155'), ('name1', 'follows'), ('p2', 'http://www.wikidata.org/prop/direct/P585'), ('name2', 'point in time')]
# [('p1', 'http://www.wikidata.org/prop/direct/P156'), ('name1', 'followed by'), ('p2', 'http://www.wikidata.org/prop/direct/P641'), ('name2', 'sport')]
# [('p1', 'http://www.wikidata.org/prop/direct/P155'), ('name1', 'follows'), ('p2', 'http://www.wikidata.org/prop/direct/P641'), ('name2', 'sport')]
# 18

# %%
# aim: get all the properties related to 'Berlin Marathon'
# result: we found the property 'participant in'
queryString = """
SELECT DISTINCT ?p1 ?name1 ?p2 ?name2
WHERE {
   # bind something
   # ?s ?p1 wd:Q161222 .
   wd:Q161222 ?p2 ?o.
   # get the label
   # ?p1 sc:name ?name1 .
   # ?p2 sc:name ?name2 .
}
LIMIT 200
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p1', 'http://www.wikidata.org/prop/direct/P1344'), ('name1', 'participant in'), ('p2', 'http://www.wikidata.org/prop/direct/P131'), ('name2', 'located in the administrative territorial entity')]
# [('p1', 'http://www.wikidata.org/prop/direct/P301'), ('name1', "category's main topic"), ('p2', 'http://www.wikidata.org/prop/direct/P131'), ('name2', 'located in the administrative territorial entity')]
# [('p1', 'http://www.wikidata.org/prop/direct/P31'), ('name1', 'instance of'), ('p2', 'http://www.wikidata.org/prop/direct/P131'), ('name2', 'located in the administrative territorial entity')]
# [('p1', 'http://www.wikidata.org/prop/direct/P3450'), ('name1', 'sports season of league or competition'), ('p2', 'http://www.wikidata.org/prop/direct/P131'), ('name2', 'located in the administrative territorial entity')]
# [('p1', 'http://www.wikidata.org/prop/direct/P527'), ('name1', 'has part'), ('p2', 'http://www.wikidata.org/prop/direct/P131'), ('name2', 'located in the administrative territorial entity')]
# [('p1', 'http://www.wikidata.org/prop/direct/P1344'), ('name1', 'participant in'), ('p2', 'http://www.wikidata.org/prop/direct/P1417'), ('name2', 'Encyclopædia Britannica Online ID')]
# [('p1', 'http://www.wikidata.org/prop/direct/P301'), ('name1', "category's main topic"), ('p2', 'http://www.wikidata.org/prop/direct/P1417'), ('name2', 'Encyclopædia Britannica Online ID')]
# [('p1', 'http://www.wikidata.org/prop/direct/P31'), ('name1', 'instance of'), ('p2', 'http://www.wikidata.org/prop/direct/P1417'), ('name2', 'Encyclopædia Britannica Online ID')]
# [('p1', 'http://www.wikidata.org/prop/direct/P3450'), ('name1', 'sports season of league or competition'), ('p2', 'http://www.wikidata.org/prop/direct/P1417'), ('name2', 'Encyclopædia Britannica Online ID')]
# [('p1', 'http://www.wikidata.org/prop/direct/P527'), ('name1', 'has part'), ('p2', 'http://www.wikidata.org/prop/direct/P1417'), ('name2', 'Encyclopædia Britannica Online ID')]
# [('p1', 'http://www.wikidata.org/prop/direct/P1344'), ('name1', 'participant in'), ('p2', 'http://www.wikidata.org/prop/direct/P17'), ('name2', 'country')]
# [('p1', 'http://www.wikidata.org/prop/direct/P301'), ('name1', "category's main topic"), ('p2', 'http://www.wikidata.org/prop/direct/P17'), ('name2', 'country')]
# [('p1', 'http://www.wikidata.org/prop/direct/P31'), ('name1', 'instance of'), ('p2', 'http://www.wikidata.org/prop/direct/P17'), ('name2', 'country')]
# [('p1', 'http://www.wikidata.org/prop/direct/P3450'), ('name1', 'sports season of league or competition'), ('p2', 'http://www.wikidata.org/prop/direct/P17'), ('name2', 'country')]
# [('p1', 'http://www.wikidata.org/prop/direct/P527'), ('name1', 'has part'), ('p2', 'http://www.wikidata.org/prop/direct/P17'), ('name2', 'country')]
# [('p1', 'http://www.wikidata.org/prop/direct/P1344'), ('name1', 'participant in'), ('p2', 'http://www.wikidata.org/prop/direct/P18'), ('name2', 'image')]
# [('p1', 'http://www.wikidata.org/prop/direct/P301'), ('name1', "category's main topic"), ('p2', 'http://www.wikidata.org/prop/direct/P18'), ('name2', 'image')]
# [('p1', 'http://www.wikidata.org/prop/direct/P31'), ('name1', 'instance of'), ('p2', 'http://www.wikidata.org/prop/direct/P18'), ('name2', 'image')]
# [('p1', 'http://www.wikidata.org/prop/direct/P3450'), ('name1', 'sports season of league or competition'), ('p2', 'http://www.wikidata.org/prop/direct/P18'), ('name2', 'image')]
# [('p1', 'http://www.wikidata.org/prop/direct/P527'), ('name1', 'has part'), ('p2', 'http://www.wikidata.org/prop/direct/P18'), ('name2', 'image')]
# [('p1', 'http://www.wikidata.org/prop/direct/P1344'), ('name1', 'participant in'), ('p2', 'http://www.wikidata.org/prop/direct/P2002'), ('name2', 'Twitter username')]
# [('p1', 'http://www.wikidata.org/prop/direct/P301'), ('name1', "category's main topic"), ('p2', 'http://www.wikidata.org/prop/direct/P2002'), ('name2', 'Twitter username')]
# [('p1', 'http://www.wikidata.org/prop/direct/P31'), ('name1', 'instance of'), ('p2', 'http://www.wikidata.org/prop/direct/P2002'), ('name2', 'Twitter username')]
# [('p1', 'http://www.wikidata.org/prop/direct/P3450'), ('name1', 'sports season of league or competition'), ('p2', 'http://www.wikidata.org/prop/direct/P2002'), ('name2', 'Twitter username')]
# [('p1', 'http://www.wikidata.org/prop/direct/P527'), ('name1', 'has part'), ('p2', 'http://www.wikidata.org/prop/direct/P2002'), ('name2', 'Twitter username')]
# [('p1', 'http://www.wikidata.org/prop/direct/P1344'), ('name1', 'participant in'), ('p2', 'http://www.wikidata.org/prop/direct/P2031'), ('name2', 'work period (start)')]
# [('p1', 'http://www.wikidata.org/prop/direct/P301'), ('name1', "category's main topic"), ('p2', 'http://www.wikidata.org/prop/direct/P2031'), ('name2', 'work period (start)')]
# [('p1', 'http://www.wikidata.org/prop/direct/P31'), ('name1', 'instance of'), ('p2', 'http://www.wikidata.org/prop/direct/P2031'), ('name2', 'work period (start)')]
# [('p1', 'http://www.wikidata.org/prop/direct/P3450'), ('name1', 'sports season of league or competition'), ('p2', 'http://www.wikidata.org/prop/direct/P2031'), ('name2', 'work period (start)')]
# [('p1', 'http://www.wikidata.org/prop/direct/P527'), ('name1', 'has part'), ('p2', 'http://www.wikidata.org/prop/direct/P2031'), ('name2', 'work period (start)')]
# [('p1', 'http://www.wikidata.org/prop/direct/P1344'), ('name1', 'participant in'), ('p2', 'http://www.wikidata.org/prop/direct/P214'), ('name2', 'VIAF ID')]
# [('p1', 'http://www.wikidata.org/prop/direct/P301'), ('name1', "category's main topic"), ('p2', 'http://www.wikidata.org/prop/direct/P214'), ('name2', 'VIAF ID')]
# [('p1', 'http://www.wikidata.org/prop/direct/P31'), ('name1', 'instance of'), ('p2', 'http://www.wikidata.org/prop/direct/P214'), ('name2', 'VIAF ID')]
# [('p1', 'http://www.wikidata.org/prop/direct/P3450'), ('name1', 'sports season of league or competition'), ('p2', 'http://www.wikidata.org/prop/direct/P214'), ('name2', 'VIAF ID')]
# [('p1', 'http://www.wikidata.org/prop/direct/P527'), ('name1', 'has part'), ('p2', 'http://www.wikidata.org/prop/direct/P214'), ('name2', 'VIAF ID')]
# [('p1', 'http://www.wikidata.org/prop/direct/P1344'), ('name1', 'participant in'), ('p2', 'http://www.wikidata.org/prop/direct/P227'), ('name2', 'GND ID')]
# [('p1', 'http://www.wikidata.org/prop/direct/P301'), ('name1', "category's main topic"), ('p2', 'http://www.wikidata.org/prop/direct/P227'), ('name2', 'GND ID')]
# [('p1', 'http://www.wikidata.org/prop/direct/P31'), ('name1', 'instance of'), ('p2', 'http://www.wikidata.org/prop/direct/P227'), ('name2', 'GND ID')]
# [('p1', 'http://www.wikidata.org/prop/direct/P3450'), ('name1', 'sports season of league or competition'), ('p2', 'http://www.wikidata.org/prop/direct/P227'), ('name2', 'GND ID')]
# [('p1', 'http://www.wikidata.org/prop/direct/P527'), ('name1', 'has part'), ('p2', 'http://www.wikidata.org/prop/direct/P227'), ('name2', 'GND ID')]
# [('p1', 'http://www.wikidata.org/prop/direct/P1344'), ('name1', 'participant in'), ('p2', 'http://www.wikidata.org/prop/direct/P276'), ('name2', 'location')]
# [('p1', 'http://www.wikidata.org/prop/direct/P301'), ('name1', "category's main topic"), ('p2', 'http://www.wikidata.org/prop/direct/P276'), ('name2', 'location')]
# [('p1', 'http://www.wikidata.org/prop/direct/P31'), ('name1', 'instance of'), ('p2', 'http://www.wikidata.org/prop/direct/P276'), ('name2', 'location')]
# [('p1', 'http://www.wikidata.org/prop/direct/P3450'), ('name1', 'sports season of league or competition'), ('p2', 'http://www.wikidata.org/prop/direct/P276'), ('name2', 'location')]
# [('p1', 'http://www.wikidata.org/prop/direct/P527'), ('name1', 'has part'), ('p2', 'http://www.wikidata.org/prop/direct/P276'), ('name2', 'location')]
# [('p1', 'http://www.wikidata.org/prop/direct/P1344'), ('name1', 'participant in'), ('p2', 'http://www.wikidata.org/prop/direct/P279'), ('name2', 'subclass of')]
# [('p1', 'http://www.wikidata.org/prop/direct/P301'), ('name1', "category's main topic"), ('p2', 'http://www.wikidata.org/prop/direct/P279'), ('name2', 'subclass of')]
# [('p1', 'http://www.wikidata.org/prop/direct/P31'), ('name1', 'instance of'), ('p2', 'http://www.wikidata.org/prop/direct/P279'), ('name2', 'subclass of')]
# [('p1', 'http://www.wikidata.org/prop/direct/P3450'), ('name1', 'sports season of league or competition'), ('p2', 'http://www.wikidata.org/prop/direct/P279'), ('name2', 'subclass of')]
# [('p1', 'http://www.wikidata.org/prop/direct/P527'), ('name1', 'has part'), ('p2', 'http://www.wikidata.org/prop/direct/P279'), ('name2', 'subclass of')]
# [('p1', 'http://www.wikidata.org/prop/direct/P1344'), ('name1', 'participant in'), ('p2', 'http://www.wikidata.org/prop/direct/P2922'), ('name2', 'month of the year')]
# [('p1', 'http://www.wikidata.org/prop/direct/P301'), ('name1', "category's main topic"), ('p2', 'http://www.wikidata.org/prop/direct/P2922'), ('name2', 'month of the year')]
# [('p1', 'http://www.wikidata.org/prop/direct/P31'), ('name1', 'instance of'), ('p2', 'http://www.wikidata.org/prop/direct/P2922'), ('name2', 'month of the year')]
# [('p1', 'http://www.wikidata.org/prop/direct/P3450'), ('name1', 'sports season of league or competition'), ('p2', 'http://www.wikidata.org/prop/direct/P2922'), ('name2', 'month of the year')]
# [('p1', 'http://www.wikidata.org/prop/direct/P527'), ('name1', 'has part'), ('p2', 'http://www.wikidata.org/prop/direct/P2922'), ('name2', 'month of the year')]
# [('p1', 'http://www.wikidata.org/prop/direct/P1344'), ('name1', 'participant in'), ('p2', 'http://www.wikidata.org/prop/direct/P31'), ('name2', 'instance of')]
# [('p1', 'http://www.wikidata.org/prop/direct/P301'), ('name1', "category's main topic"), ('p2', 'http://www.wikidata.org/prop/direct/P31'), ('name2', 'instance of')]
# [('p1', 'http://www.wikidata.org/prop/direct/P31'), ('name1', 'instance of'), ('p2', 'http://www.wikidata.org/prop/direct/P31'), ('name2', 'instance of')]
# [('p1', 'http://www.wikidata.org/prop/direct/P3450'), ('name1', 'sports season of league or competition'), ('p2', 'http://www.wikidata.org/prop/direct/P31'), ('name2', 'instance of')]
# [('p1', 'http://www.wikidata.org/prop/direct/P527'), ('name1', 'has part'), ('p2', 'http://www.wikidata.org/prop/direct/P31'), ('name2', 'instance of')]
# [('p1', 'http://www.wikidata.org/prop/direct/P1344'), ('name1', 'participant in'), ('p2', 'http://www.wikidata.org/prop/direct/P3417'), ('name2', 'Quora topic ID')]
# [('p1', 'http://www.wikidata.org/prop/direct/P301'), ('name1', "category's main topic"), ('p2', 'http://www.wikidata.org/prop/direct/P3417'), ('name2', 'Quora topic ID')]
# [('p1', 'http://www.wikidata.org/prop/direct/P31'), ('name1', 'instance of'), ('p2', 'http://www.wikidata.org/prop/direct/P3417'), ('name2', 'Quora topic ID')]
# [('p1', 'http://www.wikidata.org/prop/direct/P3450'), ('name1', 'sports season of league or competition'), ('p2', 'http://www.wikidata.org/prop/direct/P3417'), ('name2', 'Quora topic ID')]
# [('p1', 'http://www.wikidata.org/prop/direct/P527'), ('name1', 'has part'), ('p2', 'http://www.wikidata.org/prop/direct/P3417'), ('name2', 'Quora topic ID')]
# [('p1', 'http://www.wikidata.org/prop/direct/P1344'), ('name1', 'participant in'), ('p2', 'http://www.wikidata.org/prop/direct/P373'), ('name2', 'Commons category')]
# [('p1', 'http://www.wikidata.org/prop/direct/P301'), ('name1', "category's main topic"), ('p2', 'http://www.wikidata.org/prop/direct/P373'), ('name2', 'Commons category')]
# [('p1', 'http://www.wikidata.org/prop/direct/P31'), ('name1', 'instance of'), ('p2', 'http://www.wikidata.org/prop/direct/P373'), ('name2', 'Commons category')]
# [('p1', 'http://www.wikidata.org/prop/direct/P3450'), ('name1', 'sports season of league or competition'), ('p2', 'http://www.wikidata.org/prop/direct/P373'), ('name2', 'Commons category')]
# [('p1', 'http://www.wikidata.org/prop/direct/P527'), ('name1', 'has part'), ('p2', 'http://www.wikidata.org/prop/direct/P373'), ('name2', 'Commons category')]
# [('p1', 'http://www.wikidata.org/prop/direct/P1344'), ('name1', 'participant in'), ('p2', 'http://www.wikidata.org/prop/direct/P571'), ('name2', 'inception')]
# [('p1', 'http://www.wikidata.org/prop/direct/P301'), ('name1', "category's main topic"), ('p2', 'http://www.wikidata.org/prop/direct/P571'), ('name2', 'inception')]
# [('p1', 'http://www.wikidata.org/prop/direct/P31'), ('name1', 'instance of'), ('p2', 'http://www.wikidata.org/prop/direct/P571'), ('name2', 'inception')]
# [('p1', 'http://www.wikidata.org/prop/direct/P3450'), ('name1', 'sports season of league or competition'), ('p2', 'http://www.wikidata.org/prop/direct/P571'), ('name2', 'inception')]
# [('p1', 'http://www.wikidata.org/prop/direct/P527'), ('name1', 'has part'), ('p2', 'http://www.wikidata.org/prop/direct/P571'), ('name2', 'inception')]
# [('p1', 'http://www.wikidata.org/prop/direct/P1344'), ('name1', 'participant in'), ('p2', 'http://www.wikidata.org/prop/direct/P641'), ('name2', 'sport')]
# [('p1', 'http://www.wikidata.org/prop/direct/P301'), ('name1', "category's main topic"), ('p2', 'http://www.wikidata.org/prop/direct/P641'), ('name2', 'sport')]
# [('p1', 'http://www.wikidata.org/prop/direct/P31'), ('name1', 'instance of'), ('p2', 'http://www.wikidata.org/prop/direct/P641'), ('name2', 'sport')]
# [('p1', 'http://www.wikidata.org/prop/direct/P3450'), ('name1', 'sports season of league or competition'), ('p2', 'http://www.wikidata.org/prop/direct/P641'), ('name2', 'sport')]
# [('p1', 'http://www.wikidata.org/prop/direct/P527'), ('name1', 'has part'), ('p2', 'http://www.wikidata.org/prop/direct/P641'), ('name2', 'sport')]
# [('p1', 'http://www.wikidata.org/prop/direct/P1344'), ('name1', 'participant in'), ('p2', 'http://www.wikidata.org/prop/direct/P646'), ('name2', 'Freebase ID')]
# [('p1', 'http://www.wikidata.org/prop/direct/P301'), ('name1', "category's main topic"), ('p2', 'http://www.wikidata.org/prop/direct/P646'), ('name2', 'Freebase ID')]
# [('p1', 'http://www.wikidata.org/prop/direct/P31'), ('name1', 'instance of'), ('p2', 'http://www.wikidata.org/prop/direct/P646'), ('name2', 'Freebase ID')]
# [('p1', 'http://www.wikidata.org/prop/direct/P3450'), ('name1', 'sports season of league or competition'), ('p2', 'http://www.wikidata.org/prop/direct/P646'), ('name2', 'Freebase ID')]
# [('p1', 'http://www.wikidata.org/prop/direct/P527'), ('name1', 'has part'), ('p2', 'http://www.wikidata.org/prop/direct/P646'), ('name2', 'Freebase ID')]
# [('p1', 'http://www.wikidata.org/prop/direct/P1344'), ('name1', 'participant in'), ('p2', 'http://www.wikidata.org/prop/direct/P856'), ('name2', 'official website')]
# [('p1', 'http://www.wikidata.org/prop/direct/P301'), ('name1', "category's main topic"), ('p2', 'http://www.wikidata.org/prop/direct/P856'), ('name2', 'official website')]
# [('p1', 'http://www.wikidata.org/prop/direct/P31'), ('name1', 'instance of'), ('p2', 'http://www.wikidata.org/prop/direct/P856'), ('name2', 'official website')]
# [('p1', 'http://www.wikidata.org/prop/direct/P3450'), ('name1', 'sports season of league or competition'), ('p2', 'http://www.wikidata.org/prop/direct/P856'), ('name2', 'official website')]
# [('p1', 'http://www.wikidata.org/prop/direct/P527'), ('name1', 'has part'), ('p2', 'http://www.wikidata.org/prop/direct/P856'), ('name2', 'official website')]
# [('p1', 'http://www.wikidata.org/prop/direct/P1344'), ('name1', 'participant in'), ('p2', 'http://www.wikidata.org/prop/direct/P859'), ('name2', 'sponsor')]
# [('p1', 'http://www.wikidata.org/prop/direct/P301'), ('name1', "category's main topic"), ('p2', 'http://www.wikidata.org/prop/direct/P859'), ('name2', 'sponsor')]
# [('p1', 'http://www.wikidata.org/prop/direct/P31'), ('name1', 'instance of'), ('p2', 'http://www.wikidata.org/prop/direct/P859'), ('name2', 'sponsor')]
# [('p1', 'http://www.wikidata.org/prop/direct/P3450'), ('name1', 'sports season of league or competition'), ('p2', 'http://www.wikidata.org/prop/direct/P859'), ('name2', 'sponsor')]
# [('p1', 'http://www.wikidata.org/prop/direct/P527'), ('name1', 'has part'), ('p2', 'http://www.wikidata.org/prop/direct/P859'), ('name2', 'sponsor')]
# [('p1', 'http://www.wikidata.org/prop/direct/P1344'), ('name1', 'participant in'), ('p2', 'http://www.wikidata.org/prop/direct/P8687'), ('name2', 'social media followers')]
# [('p1', 'http://www.wikidata.org/prop/direct/P301'), ('name1', "category's main topic"), ('p2', 'http://www.wikidata.org/prop/direct/P8687'), ('name2', 'social media followers')]
# [('p1', 'http://www.wikidata.org/prop/direct/P31'), ('name1', 'instance of'), ('p2', 'http://www.wikidata.org/prop/direct/P8687'), ('name2', 'social media followers')]
# [('p1', 'http://www.wikidata.org/prop/direct/P3450'), ('name1', 'sports season of league or competition'), ('p2', 'http://www.wikidata.org/prop/direct/P8687'), ('name2', 'social media followers')]
# [('p1', 'http://www.wikidata.org/prop/direct/P527'), ('name1', 'has part'), ('p2', 'http://www.wikidata.org/prop/direct/P8687'), ('name2', 'social media followers')]
# [('p1', 'http://www.wikidata.org/prop/direct/P1344'), ('name1', 'participant in'), ('p2', 'http://www.wikidata.org/prop/direct/P910'), ('name2', "topic's main category")]
# [('p1', 'http://www.wikidata.org/prop/direct/P301'), ('name1', "category's main topic"), ('p2', 'http://www.wikidata.org/prop/direct/P910'), ('name2', "topic's main category")]
# [('p1', 'http://www.wikidata.org/prop/direct/P31'), ('name1', 'instance of'), ('p2', 'http://www.wikidata.org/prop/direct/P910'), ('name2', "topic's main category")]
# [('p1', 'http://www.wikidata.org/prop/direct/P3450'), ('name1', 'sports season of league or competition'), ('p2', 'http://www.wikidata.org/prop/direct/P910'), ('name2', "topic's main category")]
# [('p1', 'http://www.wikidata.org/prop/direct/P527'), ('name1', 'has part'), ('p2', 'http://www.wikidata.org/prop/direct/P910'), ('name2', "topic's main category")]
# 105

# %%
# aim: explore the property 'victory' of 'marathon' just to see what is it related to
# result: we found a person but we don't know which marathon he or she participated in and if he or she won that marathon
queryString = """
SELECT DISTINCT ?s ?name ?p
WHERE {
   # bind something
   # ?s wdt:P2522 wd:Q40244 .
   # get the label
   # ?s sc:name ?name .
}
LIMIT 200
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('s', 'http://www.wikidata.org/entity/Q5930934'), ('name', 'Jhon Cusi Huaman')]
# 1

# %%
# aim: get all the 'participant in' in the 'Berlin Marathon'
# result: we found an athlete partecipating in the 'Berlin Marathon'
queryString = """
SELECT DISTINCT ?s ?name
WHERE {
   # bind something
   # ?s wdt:P1344 wd:Q161222 .
   # get the label
   # ?s sc:name ?name .
}
LIMIT 200
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('s', 'http://www.wikidata.org/entity/Q1705'), ('name', 'Wilson Kipsang Kiprotich')]
# 1

# %%
# aim: get all the properties of 'Wilson Kipsang Kiprotich'
# result: we didn't find any interesting properties apart from the 'country of citizenship' that will be used to group by country
queryString = """
SELECT DISTINCT ?p ?name
WHERE {
   # bind something
   wd:Q1705 ?p ?o .
   # get the label
   # ?p sc:name ?name .
}
LIMIT 200
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P1000'), ('name', 'record held')]
# [('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('p', 'http://www.wikidata.org/prop/direct/P1146'), ('name', 'World Athletics athlete ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1344'), ('name', 'participant in')]
# [('p', 'http://www.wikidata.org/prop/direct/P1412'), ('name', 'languages spoken, written or signed')]
# [('p', 'http://www.wikidata.org/prop/direct/P1447'), ('name', 'Sports-Reference.com Olympic athlete ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1741'), ('name', 'GTAA ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P18'), ('name', 'image')]
# [('p', 'http://www.wikidata.org/prop/direct/P19'), ('name', 'place of birth')]
# [('p', 'http://www.wikidata.org/prop/direct/P2048'), ('name', 'height')]
# [('p', 'http://www.wikidata.org/prop/direct/P2067'), ('name', 'mass')]
# [('p', 'http://www.wikidata.org/prop/direct/P21'), ('name', 'sex or gender')]
# [('p', 'http://www.wikidata.org/prop/direct/P2416'), ('name', 'sports discipline competed in')]
# [('p', 'http://www.wikidata.org/prop/direct/P27'), ('name', 'country of citizenship')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('name', 'instance of')]
# [('p', 'http://www.wikidata.org/prop/direct/P3171'), ('name', 'Olympic.org athlete ID (archived version)')]
# [('p', 'http://www.wikidata.org/prop/direct/P373'), ('name', 'Commons category')]
# [('p', 'http://www.wikidata.org/prop/direct/P3884'), ('name', 'Tilastopaja male athlete ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3925'), ('name', 'Track and Field Statistics male athlete ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P569'), ('name', 'date of birth')]
# [('p', 'http://www.wikidata.org/prop/direct/P5815'), ('name', 'Olympics.com athlete ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P641'), ('name', 'sport')]
# [('p', 'http://www.wikidata.org/prop/direct/P646'), ('name', 'Freebase ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P734'), ('name', 'family name')]
# [('p', 'http://www.wikidata.org/prop/direct/P735'), ('name', 'given name')]
# [('p', 'http://www.wikidata.org/prop/direct/P8286'), ('name', 'Olympedia people ID')]
# 26

# %%
# aim: get all the properties related to 'Wilson Kipsang Kiprotich'
# result: we find the property 'winner'! Let's check the subject of that property
queryString = """
SELECT DISTINCT ?p ?name
WHERE {
   # bind something
   # ?s ?p wd:Q1705 .
   # get the label
   # ?p sc:name ?name .
}
LIMIT 200
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P1346'), ('name', 'winner')]
# 1

# %%
# aim: get the subject of the property 'winner' related to the object 'Wilson Kipsang Kiprotich'
# result: we found the marathons the athlete won! We need to use the 'winner' property to get the marathon winners
queryString = """
SELECT DISTINCT ?s ?name
WHERE {
   # bind something
   # ?s wdt:P1346 wd:Q1705 .
   # get the label
   # ?s sc:name ?name .
}
LIMIT 200
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('s', 'http://www.wikidata.org/entity/Q28802674'), ('name', '2017 Tokyo Marathon')]
# [('s', 'http://www.wikidata.org/entity/Q17634742'), ('name', '2014 New York City Marathon')]
# 2

# %%
# aim: get all the european athletes who whon at least 1 european marathon ***ASK IF IT HAS TO BE JUST ONE OR CAN BE AT LEAST ONE WON MARATHON ***
# result: we found european marathons with their corresponding winners
queryString = """
SELECT DISTINCT ?winner ?winnername ?europeanmarathon
WHERE {
   # ?europeanmarathon ?p wd:Q40244 .
   
   # ?europeanmarathon wdt:P17 ?countrymarathon .
   # ?countrymarathon wdt:P30 wd:Q46 .
   # ?europeanmarathon sc:name ?name .
   
   # ?europeanmarathon wdt:P1346 ?winner .
   # ?winner sc:name ?winnername .
   
}
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('winner', 'http://www.wikidata.org/entity/Q3659293'), ('winnername', 'Carlo Durante'), ('europeanmarathon', 'http://www.wikidata.org/entity/Q4814257')]
# [('winner', 'http://www.wikidata.org/entity/Q2340625'), ('winnername', 'Koen Naert'), ('europeanmarathon', 'http://www.wikidata.org/entity/Q55780710')]
# [('winner', 'http://www.wikidata.org/entity/Q275831'), ('winnername', 'Christelle Daunay'), ('europeanmarathon', 'http://www.wikidata.org/entity/Q17496398')]
# [('winner', 'http://www.wikidata.org/entity/Q510629'), ('winnername', 'Jemima Sumgong'), ('europeanmarathon', 'http://www.wikidata.org/entity/Q23905992')]
# [('winner', 'http://www.wikidata.org/entity/Q688458'), ('winnername', 'Marcel Hug'), ('europeanmarathon', 'http://www.wikidata.org/entity/Q23905992')]
# [('winner', 'http://www.wikidata.org/entity/Q2433125'), ('winnername', 'Tilahun Regassa'), ('europeanmarathon', 'http://www.wikidata.org/entity/Q13813340')]
# [('winner', 'http://www.wikidata.org/entity/Q9119'), ('winnername', 'Kenenisa Bekele Beyecha'), ('europeanmarathon', 'http://www.wikidata.org/entity/Q16802238')]
# [('winner', 'http://www.wikidata.org/entity/Q2112488'), ('winnername', 'Tatyana McFadden'), ('europeanmarathon', 'http://www.wikidata.org/entity/Q23905992')]
# [('winner', 'http://www.wikidata.org/entity/Q16337559'), ('winnername', 'Henrique Crisóstomo'), ('europeanmarathon', 'http://www.wikidata.org/entity/Q13813997')]
# [('winner', 'http://www.wikidata.org/entity/Q9124'), ('winnername', 'Eliud Kipchoge'), ('europeanmarathon', 'http://www.wikidata.org/entity/Q23905992')]
# [('winner', 'http://www.wikidata.org/entity/Q180891'), ('winnername', 'Sergei Popov'), ('europeanmarathon', 'http://www.wikidata.org/entity/Q3229843')]
# [('winner', 'http://www.wikidata.org/entity/Q912468'), ('winnername', 'Brian Kilby'), ('europeanmarathon', 'http://www.wikidata.org/entity/Q4327940')]
# [('winner', 'http://www.wikidata.org/entity/Q519190'), ('winnername', 'Feyse Tadese'), ('europeanmarathon', 'http://www.wikidata.org/entity/Q13814026')]
# [('winner', 'http://www.wikidata.org/entity/Q2076269'), ('winnername', 'Peter Kimeli Some'), ('europeanmarathon', 'http://www.wikidata.org/entity/Q13814026')]
# [('winner', 'http://www.wikidata.org/entity/Q1359466'), ('winnername', 'Jack Holden'), ('europeanmarathon', 'http://www.wikidata.org/entity/Q3917247')]
# [('winner', 'http://www.wikidata.org/entity/Q11831849'), ('winnername', 'Purity Cherotich Rionoripo'), ('europeanmarathon', 'http://www.wikidata.org/entity/Q29053996')]
# [('winner', 'http://www.wikidata.org/entity/Q21414453'), ('winnername', 'Paul Kipchumba Lonyangata'), ('europeanmarathon', 'http://www.wikidata.org/entity/Q29053996')]
# [('winner', 'http://www.wikidata.org/entity/Q270241'), ('winnername', 'Gelete Burka'), ('europeanmarathon', 'http://www.wikidata.org/entity/Q65234870')]
# [('winner', 'http://www.wikidata.org/entity/Q271166'), ('winnername', 'Mary Jepkosgei Keitany'), ('europeanmarathon', 'http://www.wikidata.org/entity/Q29467338')]
# [('winner', 'http://www.wikidata.org/entity/Q1689117'), ('winnername', 'Jim Hogan'), ('europeanmarathon', 'http://www.wikidata.org/entity/Q4494720')]
# 20

# %%
# aim: get all the european athletes who whon at least 1 european marathon ***ASK IF IT HAS TO BE JUST ONE OR CAN BE AT LEAST ONE WON MARATHON ***
# result: we found all the winners of european marathons
queryString = """
SELECT DISTINCT ?winner ?winnername
WHERE {
   # ?europeanmarathon ?p wd:Q40244 .
   
   # ?europeanmarathon wdt:P17 ?countrymarathon .
   # ?countrymarathon wdt:P30 wd:Q46 .
   # ?europeanmarathon sc:name ?name .
   
   # ?europeanmarathon wdt:P1346 ?winner .
   # ?winner sc:name ?winnername .
   
}
LIMIT 2000
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('winner', 'http://www.wikidata.org/entity/Q3659293'), ('winnername', 'Carlo Durante')]
# [('winner', 'http://www.wikidata.org/entity/Q2340625'), ('winnername', 'Koen Naert')]
# [('winner', 'http://www.wikidata.org/entity/Q275831'), ('winnername', 'Christelle Daunay')]
# [('winner', 'http://www.wikidata.org/entity/Q510629'), ('winnername', 'Jemima Sumgong')]
# [('winner', 'http://www.wikidata.org/entity/Q688458'), ('winnername', 'Marcel Hug')]
# [('winner', 'http://www.wikidata.org/entity/Q2433125'), ('winnername', 'Tilahun Regassa')]
# [('winner', 'http://www.wikidata.org/entity/Q9119'), ('winnername', 'Kenenisa Bekele Beyecha')]
# [('winner', 'http://www.wikidata.org/entity/Q2112488'), ('winnername', 'Tatyana McFadden')]
# [('winner', 'http://www.wikidata.org/entity/Q16337559'), ('winnername', 'Henrique Crisóstomo')]
# [('winner', 'http://www.wikidata.org/entity/Q9124'), ('winnername', 'Eliud Kipchoge')]
# [('winner', 'http://www.wikidata.org/entity/Q180891'), ('winnername', 'Sergei Popov')]
# [('winner', 'http://www.wikidata.org/entity/Q912468'), ('winnername', 'Brian Kilby')]
# [('winner', 'http://www.wikidata.org/entity/Q519190'), ('winnername', 'Feyse Tadese')]
# [('winner', 'http://www.wikidata.org/entity/Q2076269'), ('winnername', 'Peter Kimeli Some')]
# [('winner', 'http://www.wikidata.org/entity/Q1359466'), ('winnername', 'Jack Holden')]
# [('winner', 'http://www.wikidata.org/entity/Q11831849'), ('winnername', 'Purity Cherotich Rionoripo')]
# [('winner', 'http://www.wikidata.org/entity/Q21414453'), ('winnername', 'Paul Kipchumba Lonyangata')]
# [('winner', 'http://www.wikidata.org/entity/Q270241'), ('winnername', 'Gelete Burka')]
# [('winner', 'http://www.wikidata.org/entity/Q271166'), ('winnername', 'Mary Jepkosgei Keitany')]
# [('winner', 'http://www.wikidata.org/entity/Q1689117'), ('winnername', 'Jim Hogan')]
# [('winner', 'http://www.wikidata.org/entity/Q1648585'), ('winnername', 'Meseret Mengistu')]
# [('winner', 'http://www.wikidata.org/entity/Q19799156'), ('winnername', 'Mark Korir')]
# [('winner', 'http://www.wikidata.org/entity/Q20898097'), ('winnername', 'Visiline Jepkesho')]
# [('winner', 'http://www.wikidata.org/entity/Q16636410'), ('winnername', 'Flomena Cheyech Daniel')]
# [('winner', 'http://www.wikidata.org/entity/Q258564'), ('winnername', 'Aselefech Mergia')]
# [('winner', 'http://www.wikidata.org/entity/Q23021432'), ('winnername', 'Cyprian Kimurgor Kotut')]
# [('winner', 'http://www.wikidata.org/entity/Q217614'), ('winnername', 'Armas Toivonen')]
# [('winner', 'http://www.wikidata.org/entity/Q15530'), ('winnername', 'Tsegaye Kebede')]
# [('winner', 'http://www.wikidata.org/entity/Q21936672'), ('winnername', 'Daniel Wanjiru')]
# [('winner', 'http://www.wikidata.org/entity/Q1343015'), ('winnername', 'Väinö Muinonen')]
# [('winner', 'http://www.wikidata.org/entity/Q354905'), ('winnername', 'Mikko Hietanen')]
# 31

# %% [markdown]
# Final query for this task

# %%
# aim: get the countries and their number of athletes who won a european marathon ***ASK IF IT HAS TO BE JUST ONE OR CAN BE AT LEAST ONE WON MARATHON ***
# result: the countries and their number of athletes who won a european marathon
queryString = """
SELECT DISTINCT ?winnercountry ?winnercountryname (COUNT(?winner) AS ?numberofwinners)
WHERE {

   # ?winner wdt:P27 ?winnercountry .
   # ?winnercountry sc:name ?winnercountryname .
   
   {
       SELECT DISTINCT ?winner ?winnername
        WHERE {
           # ?europeanmarathon ?p wd:Q40244 .

           # ?europeanmarathon wdt:P17 ?countrymarathon .
           # ?countrymarathon wdt:P30 wd:Q46 .
           # ?europeanmarathon sc:name ?name .

           # ?europeanmarathon wdt:P1346 ?winner .
           # ?winner sc:name ?winnername .

        }
   }
   
   
} GROUP BY ?winnercountry ?winnercountryname
LIMIT 200
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('winnercountry', 'http://www.wikidata.org/entity/Q38'), ('winnercountryname', 'Italy'), ('numberofwinners', '1')]
# [('winnercountry', 'http://www.wikidata.org/entity/Q31'), ('winnercountryname', 'Belgium'), ('numberofwinners', '1')]
# [('winnercountry', 'http://www.wikidata.org/entity/Q142'), ('winnercountryname', 'France'), ('numberofwinners', '1')]
# [('winnercountry', 'http://www.wikidata.org/entity/Q33'), ('winnercountryname', 'Finland'), ('numberofwinners', '3')]
# [('winnercountry', 'http://www.wikidata.org/entity/Q114'), ('winnercountryname', 'Kenya'), ('numberofwinners', '11')]
# [('winnercountry', 'http://www.wikidata.org/entity/Q45'), ('winnercountryname', 'Portugal'), ('numberofwinners', '1')]
# [('winnercountry', 'http://www.wikidata.org/entity/Q30'), ('winnercountryname', 'United States of America'), ('numberofwinners', '1')]
# [('winnercountry', 'http://www.wikidata.org/entity/Q145'), ('winnercountryname', 'United Kingdom'), ('numberofwinners', '3')]
# [('winnercountry', 'http://www.wikidata.org/entity/Q15180'), ('winnercountryname', 'Soviet Union'), ('numberofwinners', '1')]
# [('winnercountry', 'http://www.wikidata.org/entity/Q159'), ('winnercountryname', 'Russia'), ('numberofwinners', '1')]
# [('winnercountry', 'http://www.wikidata.org/entity/Q39'), ('winnercountryname', 'Switzerland'), ('numberofwinners', '1')]
# [('winnercountry', 'http://www.wikidata.org/entity/Q115'), ('winnercountryname', 'Ethiopia'), ('numberofwinners', '7')]
# 12

# %% [markdown]
# ## Task 5
# Identify the BGP for Olympic Games

# %%
# aim: 'athletics' is for sure an Olympic Discipline. We check its properties
# result: we found the properties 'has part' and 'subclass of' 
queryString = """
SELECT DISTINCT ?p ?name
WHERE {
   # bind something
   wd:Q542 ?p ?obj .
   # get the label
   # ?p sc:name ?name.
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P2869'), ('name', 'record or record progression')]
# [('p', 'http://www.wikidata.org/prop/direct/P1014'), ('name', 'Art & Architecture Thesaurus ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1036'), ('name', 'Dewey Decimal Classification')]
# [('p', 'http://www.wikidata.org/prop/direct/P1151'), ('name', "topic's main Wikimedia portal")]
# [('p', 'http://www.wikidata.org/prop/direct/P1225'), ('name', 'U.S. National Archives Identifier')]
# [('p', 'http://www.wikidata.org/prop/direct/P1245'), ('name', 'OmegaWiki Defined Meaning')]
# [('p', 'http://www.wikidata.org/prop/direct/P1282'), ('name', 'OpenStreetMap tag or key')]
# [('p', 'http://www.wikidata.org/prop/direct/P1296'), ('name', 'Gran Enciclopèdia Catalana ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1343'), ('name', 'described by source')]
# [('p', 'http://www.wikidata.org/prop/direct/P1417'), ('name', 'Encyclopædia Britannica Online ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1424'), ('name', "topic's main template")]
# [('p', 'http://www.wikidata.org/prop/direct/P18'), ('name', 'image')]
# [('p', 'http://www.wikidata.org/prop/direct/P1807'), ('name', 'Great Aragonese Encyclopedia ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1889'), ('name', 'different from')]
# [('p', 'http://www.wikidata.org/prop/direct/P227'), ('name', 'GND ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2283'), ('name', 'uses')]
# [('p', 'http://www.wikidata.org/prop/direct/P2347'), ('name', 'YSO ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P244'), ('name', 'Library of Congress authority ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P268'), ('name', 'Bibliothèque nationale de France ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('name', 'subclass of')]
# [('p', 'http://www.wikidata.org/prop/direct/P2910'), ('name', 'icon')]
# [('p', 'http://www.wikidata.org/prop/direct/P3095'), ('name', 'practiced by')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('name', 'instance of')]
# [('p', 'http://www.wikidata.org/prop/direct/P3219'), ('name', 'Encyclopædia Universalis ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3365'), ('name', 'Treccani ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3417'), ('name', 'Quora topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P349'), ('name', 'National Diet Library ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3509'), ('name', 'Dagens Nyheter topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3553'), ('name', 'Zhihu topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P373'), ('name', 'Commons category')]
# [('p', 'http://www.wikidata.org/prop/direct/P3911'), ('name', 'STW Thesaurus for Economics ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P4212'), ('name', 'PACTOLS thesaurus ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P4223'), ('name', "Treccani's Enciclopedia Italiana ID")]
# [('p', 'http://www.wikidata.org/prop/direct/P4527'), ('name', 'UK Parliament thesaurus ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P4613'), ('name', 'Encyclopedia of Modern Ukraine ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5008'), ('name', 'on focus list of Wikimedia project')]
# [('p', 'http://www.wikidata.org/prop/direct/P5019'), ('name', 'Brockhaus Enzyklopädie online ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P508'), ('name', 'BNCF Thesaurus ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5198'), ('name', 'ASC Leiden Thesaurus ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('name', 'has part')]
# [('p', 'http://www.wikidata.org/prop/direct/P5513'), ('name', "Enciclopèdia de l'Esport Català ID")]
# [('p', 'http://www.wikidata.org/prop/direct/P5748'), ('name', 'Basisklassifikation')]
# [('p', 'http://www.wikidata.org/prop/direct/P6104'), ('name', 'maintained by WikiProject')]
# [('p', 'http://www.wikidata.org/prop/direct/P6262'), ('name', 'Fandom article ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6293'), ('name', 'YSA ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P646'), ('name', 'Freebase ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6573'), ('name', 'Klexikon article ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6870'), ('name', 'Latvian National Encyclopedia Online ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7033'), ('name', 'Australian Educational Vocabulary ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7388'), ('name', 'Great Encyclopedia of Navarre ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7818'), ('name', 'French Vikidia ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P797'), ('name', 'authority')]
# [('p', 'http://www.wikidata.org/prop/direct/P8135'), ('name', 'Encyclopedia of České Budějovice ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8248'), ('name', 'Colon Classification')]
# [('p', 'http://www.wikidata.org/prop/direct/P8309'), ('name', 'Yle topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8785'), ('name', 'AniDB tag ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P910'), ('name', "topic's main category")]
# [('p', 'http://www.wikidata.org/prop/direct/P920'), ('name', 'LEM ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P9304'), ('name', 'Encyclopedia of Melbourne ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P9873'), ('name', 'Enciclopedia dello Sport ID')]
# 60

# %%
# aim: check the properties 'part of' and 'subclass of' related to 'athletics'
# result: we found the object 'Olympic sport'
queryString = """
SELECT DISTINCT ?obj ?name
WHERE {
   # bind something
   wd:Q542 ?p ?obj .
   # get the label
   # ?obj sc:name ?name .
   FILTER (?p IN (wdt:P527,wdt:P279))
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('obj', 'http://www.wikidata.org/entity/Q3312129'), ('name', 'track and field')]
# [('obj', 'http://www.wikidata.org/entity/Q3216963'), ('name', 'throwing event')]
# [('obj', 'http://www.wikidata.org/entity/Q11047409'), ('name', 'athletic culture')]
# [('obj', 'http://www.wikidata.org/entity/Q21467672'), ('name', 'running disciplines of track and field')]
# [('obj', 'http://www.wikidata.org/entity/Q10235779'), ('name', 'indoor athletics')]
# [('obj', 'http://www.wikidata.org/entity/Q202391'), ('name', 'racewalking')]
# [('obj', 'http://www.wikidata.org/entity/Q212434'), ('name', 'Olympic sport')]
# [('obj', 'http://www.wikidata.org/entity/Q3924425'), ('name', 'combined track and field events')]
# [('obj', 'http://www.wikidata.org/entity/Q52177345'), ('name', 'technical disciplines of athletics')]
# [('obj', 'http://www.wikidata.org/entity/Q1151752'), ('name', 'jumping')]
# 10

# %%
# aim: check the properties of 'Olympic sport'
# result: we found the properties 'part of' and 'subclass of' 
queryString = """
SELECT DISTINCT ?p ?name
WHERE {
   # bind something
   wd:Q212434 ?p ?obj .
   # get the label
   # ?p sc:name ?name.
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P1424'), ('name', "topic's main template")]
# [('p', 'http://www.wikidata.org/prop/direct/P18'), ('name', 'image')]
# [('p', 'http://www.wikidata.org/prop/direct/P1889'), ('name', 'different from')]
# [('p', 'http://www.wikidata.org/prop/direct/P2670'), ('name', 'has parts of the class')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('name', 'subclass of')]
# [('p', 'http://www.wikidata.org/prop/direct/P3095'), ('name', 'practiced by')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('name', 'instance of')]
# [('p', 'http://www.wikidata.org/prop/direct/P3417'), ('name', 'Quora topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P349'), ('name', 'National Diet Library ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P361'), ('name', 'part of')]
# [('p', 'http://www.wikidata.org/prop/direct/P373'), ('name', 'Commons category')]
# [('p', 'http://www.wikidata.org/prop/direct/P5250'), ('name', 'IAB code')]
# [('p', 'http://www.wikidata.org/prop/direct/P6366'), ('name', 'Microsoft Academic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P646'), ('name', 'Freebase ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P691'), ('name', 'NKCR AUT ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7818'), ('name', 'French Vikidia ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8408'), ('name', 'KBpedia ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P910'), ('name', "topic's main category")]
# 18

# %% [markdown]
# Final query for this task

# %%
# aim: check the properties 'part of' and 'subclass of' related to 'athletics'
# result: we found the object 'Olympic Games'
queryString = """
SELECT DISTINCT ?obj ?name
WHERE {
   # bind something
   wd:Q212434 ?p ?obj .
   # get the label
   # ?obj sc:name ?name .
   FILTER (?p IN (wdt:P361,wdt:P279))
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('obj', 'http://www.wikidata.org/entity/Q51031626'), ('name', 'sport competition at a multi-sport event')]
# [('obj', 'http://www.wikidata.org/entity/Q349'), ('name', 'sport')]
# [('obj', 'http://www.wikidata.org/entity/Q5389'), ('name', 'Olympic Games')]
# 3

# %% [markdown]
# ## Task 6
# Consider only the summer olympic games of 2004-2008-2012-2016. Return the number of marathon runners who had partecipated to all these editions group by their country of citizenship (if the runner partecipated in more than one edition of the game, consider him/her only once) (the result set must be a list of country IRI, label and #marathon runners)

# %%
# aim: get all the properties of 'Olympic Games'
# result: all the properties of 'Olympic Games'
queryString = """
SELECT DISTINCT ?p ?name
WHERE {
   # bind something
   wd:Q5389 ?p ?obj .
   # get the label
   # ?p sc:name ?name .
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P1051'), ('name', 'PSH ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1151'), ('name', "topic's main Wikimedia portal")]
# [('p', 'http://www.wikidata.org/prop/direct/P1225'), ('name', 'U.S. National Archives Identifier')]
# [('p', 'http://www.wikidata.org/prop/direct/P1245'), ('name', 'OmegaWiki Defined Meaning')]
# [('p', 'http://www.wikidata.org/prop/direct/P1296'), ('name', 'Gran Enciclopèdia Catalana ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1343'), ('name', 'described by source')]
# [('p', 'http://www.wikidata.org/prop/direct/P1417'), ('name', 'Encyclopædia Britannica Online ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1424'), ('name', "topic's main template")]
# [('p', 'http://www.wikidata.org/prop/direct/P1546'), ('name', 'motto')]
# [('p', 'http://www.wikidata.org/prop/direct/P163'), ('name', 'flag')]
# [('p', 'http://www.wikidata.org/prop/direct/P18'), ('name', 'image')]
# [('p', 'http://www.wikidata.org/prop/direct/P1807'), ('name', 'Great Aragonese Encyclopedia ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1889'), ('name', 'different from')]
# [('p', 'http://www.wikidata.org/prop/direct/P2002'), ('name', 'Twitter username')]
# [('p', 'http://www.wikidata.org/prop/direct/P214'), ('name', 'VIAF ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2257'), ('name', 'event interval')]
# [('p', 'http://www.wikidata.org/prop/direct/P227'), ('name', 'GND ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2347'), ('name', 'YSO ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2397'), ('name', 'YouTube channel ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P244'), ('name', 'Library of Congress authority ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2581'), ('name', 'BabelNet ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2670'), ('name', 'has parts of the class')]
# [('p', 'http://www.wikidata.org/prop/direct/P268'), ('name', 'Bibliothèque nationale de France ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P269'), ('name', 'IdRef ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('name', 'subclass of')]
# [('p', 'http://www.wikidata.org/prop/direct/P2924'), ('name', 'Great Russian Encyclopedia Online ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2959'), ('name', 'permanent duplicated item')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('name', 'instance of')]
# [('p', 'http://www.wikidata.org/prop/direct/P3219'), ('name', 'Encyclopædia Universalis ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3222'), ('name', 'NE.se ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3414'), ('name', 'Yle Areena item ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3417'), ('name', 'Quora topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P373'), ('name', 'Commons category')]
# [('p', 'http://www.wikidata.org/prop/direct/P3827'), ('name', 'JSTOR topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3916'), ('name', 'UNESCO Thesaurus ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3984'), ('name', 'subreddit')]
# [('p', 'http://www.wikidata.org/prop/direct/P41'), ('name', 'flag image')]
# [('p', 'http://www.wikidata.org/prop/direct/P4210'), ('name', 'Bashkir encyclopedia (Bashkir version) ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P4211'), ('name', 'Bashkir encyclopedia (Russian version) ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P4527'), ('name', 'UK Parliament thesaurus ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P4622'), ('name', 'trophy awarded')]
# [('p', 'http://www.wikidata.org/prop/direct/P5008'), ('name', 'on focus list of Wikimedia project')]
# [('p', 'http://www.wikidata.org/prop/direct/P508'), ('name', 'BNCF Thesaurus ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5429'), ('name', 'IPTC NewsCode')]
# [('p', 'http://www.wikidata.org/prop/direct/P571'), ('name', 'inception')]
# [('p', 'http://www.wikidata.org/prop/direct/P5905'), ('name', 'Comic Vine ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6058'), ('name', 'Larousse ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6104'), ('name', 'maintained by WikiProject')]
# [('p', 'http://www.wikidata.org/prop/direct/P6181'), ('name', 'Disney A to Z ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6293'), ('name', 'YSA ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6328'), ('name', 'Politika topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6363'), ('name', 'WordLift URL')]
# [('p', 'http://www.wikidata.org/prop/direct/P6404'), ('name', "Treccani's Dizionario di Storia ID")]
# [('p', 'http://www.wikidata.org/prop/direct/P641'), ('name', 'sport')]
# [('p', 'http://www.wikidata.org/prop/direct/P646'), ('name', 'Freebase ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6573'), ('name', 'Klexikon article ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6622'), ('name', 'Le Parisien tag ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P664'), ('name', 'organizer')]
# [('p', 'http://www.wikidata.org/prop/direct/P6900'), ('name', 'NicoNicoPedia ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P691'), ('name', 'NKCR AUT ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7818'), ('name', 'French Vikidia ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7827'), ('name', 'Spanish Vikidia ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7832'), ('name', 'Basque Vikidia ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7859'), ('name', 'WorldCat Identities ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8309'), ('name', 'Yle topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8408'), ('name', 'KBpedia ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P856'), ('name', 'official website')]
# [('p', 'http://www.wikidata.org/prop/direct/P859'), ('name', 'sponsor')]
# [('p', 'http://www.wikidata.org/prop/direct/P8687'), ('name', 'social media followers')]
# [('p', 'http://www.wikidata.org/prop/direct/P8785'), ('name', 'AniDB tag ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P902'), ('name', 'HDS ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P906'), ('name', 'SELIBR ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P910'), ('name', "topic's main category")]
# [('p', 'http://www.wikidata.org/prop/direct/P935'), ('name', 'Commons gallery')]
# [('p', 'http://www.wikidata.org/prop/direct/P948'), ('name', 'page banner')]
# [('p', 'http://www.wikidata.org/prop/direct/P949'), ('name', 'National Library of Israel ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P950'), ('name', 'Biblioteca Nacional de España ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P9629'), ('name', 'Armeniapedia ID')]
# 78

# %%
# aim: try to find if there exist subjects that are 'instance of' 'Olympic Games'
# result: the result set is empty
queryString = """
SELECT DISTINCT ?s ?name
WHERE {
   # bind something
   # ?s wdt:P31 wd:Q5389 .
   # get the label
   # ?s sc:name ?name .
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# Empty

# %%
# aim: find the properties related to 'Olympic Games'
# result: we found the 'subclass of' property that could be useful
queryString = """
SELECT DISTINCT ?p ?name
WHERE {
   # bind something
   # ?s ?p wd:Q5389 .
   # get the label
   # ?p sc:name ?name .
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P1423'), ('name', 'template has topic')]
# [('p', 'http://www.wikidata.org/prop/direct/P101'), ('name', 'field of work')]
# [('p', 'http://www.wikidata.org/prop/direct/P1269'), ('name', 'facet of')]
# [('p', 'http://www.wikidata.org/prop/direct/P1344'), ('name', 'participant in')]
# [('p', 'http://www.wikidata.org/prop/direct/P138'), ('name', 'named after')]
# [('p', 'http://www.wikidata.org/prop/direct/P156'), ('name', 'followed by')]
# [('p', 'http://www.wikidata.org/prop/direct/P166'), ('name', 'award received')]
# [('p', 'http://www.wikidata.org/prop/direct/P1889'), ('name', 'different from')]
# [('p', 'http://www.wikidata.org/prop/direct/P2522'), ('name', 'victory')]
# [('p', 'http://www.wikidata.org/prop/direct/P2650'), ('name', 'interested in')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('name', 'subclass of')]
# [('p', 'http://www.wikidata.org/prop/direct/P2959'), ('name', 'permanent duplicated item')]
# [('p', 'http://www.wikidata.org/prop/direct/P301'), ('name', "category's main topic")]
# [('p', 'http://www.wikidata.org/prop/direct/P360'), ('name', 'is a list of')]
# [('p', 'http://www.wikidata.org/prop/direct/P361'), ('name', 'part of')]
# [('p', 'http://www.wikidata.org/prop/direct/P366'), ('name', 'use')]
# [('p', 'http://www.wikidata.org/prop/direct/P641'), ('name', 'sport')]
# [('p', 'http://www.wikidata.org/prop/direct/P793'), ('name', 'significant event')]
# [('p', 'http://www.wikidata.org/prop/direct/P921'), ('name', 'main subject')]
# [('p', 'http://www.wikidata.org/prop/direct/P971'), ('name', 'category combines topics')]
# [('p', 'http://www.wikidata.org/prop/direct/P1204'), ('name', "Wikimedia portal's main topic")]
# [('p', 'http://www.wikidata.org/prop/direct/P1855'), ('name', 'Wikidata property example')]
# 22

# %%
# aim: try to find if there exist subjects that are 'subclass of' 'Olympic Games'
# result: we found 'Summer Olympic Games'. Maybe there are subjects that are 'instance of' 'Summer Olympic Games'
queryString = """
SELECT DISTINCT ?p ?name ?s ?sname
WHERE {
   # bind something
   # ?s ?p wd:Q5389 .
   # get the label
   # ?p sc:name ?name .
   # ?s sc:name ?sname .
   FILTER REGEX(?sname,"summer","i").
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('name', 'subclass of'), ('s', 'http://www.wikidata.org/entity/Q159821'), ('sname', 'Summer Olympic Games')]
# [('p', 'http://www.wikidata.org/prop/direct/P921'), ('name', 'main subject'), ('s', 'http://www.wikidata.org/entity/Q106087337'), ('sname', 'Summer Olympics in Athens 2004')]
# [('p', 'http://www.wikidata.org/prop/direct/P971'), ('name', 'category combines topics'), ('s', 'http://www.wikidata.org/entity/Q7215607'), ('sname', 'Category:2012 Summer Olympics')]
# [('p', 'http://www.wikidata.org/prop/direct/P971'), ('name', 'category combines topics'), ('s', 'http://www.wikidata.org/entity/Q25322394'), ('sname', "Category:Cycling at the Summer Olympics – Men's keirin")]
# [('p', 'http://www.wikidata.org/prop/direct/P971'), ('name', 'category combines topics'), ('s', 'http://www.wikidata.org/entity/Q8204577'), ('sname', 'Category:2016 Summer Olympics')]
# [('p', 'http://www.wikidata.org/prop/direct/P971'), ('name', 'category combines topics'), ('s', 'http://www.wikidata.org/entity/Q32086046'), ('sname', "Category:Cycling at the Summer Olympics – Women's keirin")]
# [('p', 'http://www.wikidata.org/prop/direct/P971'), ('name', 'category combines topics'), ('s', 'http://www.wikidata.org/entity/Q25172589'), ('sname', "Category:Cycling at the Summer Olympics – Women's points race")]
# [('p', 'http://www.wikidata.org/prop/direct/P971'), ('name', 'category combines topics'), ('s', 'http://www.wikidata.org/entity/Q7215606'), ('sname', 'Category:2004 Summer Olympics')]
# 8

# %%
# aim: try to find if there exist subjects that are 'instance of' 'Olympic Games'
# result: we found 'Summer Olympic Games 2004','Summer Olympic Games 2008',... We should investigate about the marathons of these years
queryString = """
SELECT DISTINCT ?s ?sname
WHERE {
   # bind something
   # ?s wdt:P31 wd:Q159821 .
   # get the label
   # ?s sc:name ?sname .
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('s', 'http://www.wikidata.org/entity/Q8098'), ('sname', '1904 Summer Olympics')]
# [('s', 'http://www.wikidata.org/entity/Q8150'), ('sname', '1936 Summer Olympics')]
# [('s', 'http://www.wikidata.org/entity/Q8415'), ('sname', '1960 Summer Olympics')]
# [('s', 'http://www.wikidata.org/entity/Q181278'), ('sname', '2020 Summer Olympics')]
# [('s', 'http://www.wikidata.org/entity/Q8088'), ('sname', '1900 Summer Olympics')]
# [('s', 'http://www.wikidata.org/entity/Q8438'), ('sname', '1972 Summer Olympics')]
# [('s', 'http://www.wikidata.org/entity/Q8444'), ('sname', '1976 Summer Olympics')]
# [('s', 'http://www.wikidata.org/entity/Q8470'), ('sname', '1988 Summer Olympics')]
# [('s', 'http://www.wikidata.org/entity/Q8488'), ('sname', '1992 Summer Olympics')]
# [('s', 'http://www.wikidata.org/entity/Q8531'), ('sname', '1996 Summer Olympics')]
# [('s', 'http://www.wikidata.org/entity/Q8544'), ('sname', '2000 Summer Olympics')]
# [('s', 'http://www.wikidata.org/entity/Q8558'), ('sname', '2004 Summer Olympics')]
# [('s', 'http://www.wikidata.org/entity/Q8567'), ('sname', '2008 Summer Olympics')]
# [('s', 'http://www.wikidata.org/entity/Q8577'), ('sname', '2012 Summer Olympics')]
# [('s', 'http://www.wikidata.org/entity/Q8613'), ('sname', '2016 Summer Olympics')]
# [('s', 'http://www.wikidata.org/entity/Q8128'), ('sname', '1920 Summer Olympics')]
# [('s', 'http://www.wikidata.org/entity/Q8132'), ('sname', '1924 Summer Olympics')]
# [('s', 'http://www.wikidata.org/entity/Q8138'), ('sname', '1928 Summer Olympics')]
# [('s', 'http://www.wikidata.org/entity/Q8143'), ('sname', '1932 Summer Olympics')]
# [('s', 'http://www.wikidata.org/entity/Q8420'), ('sname', '1964 Summer Olympics')]
# [('s', 'http://www.wikidata.org/entity/Q8429'), ('sname', '1968 Summer Olympics')]
# [('s', 'http://www.wikidata.org/entity/Q8111'), ('sname', '1908 Summer Olympics')]
# [('s', 'http://www.wikidata.org/entity/Q8118'), ('sname', '1912 Summer Olympics')]
# [('s', 'http://www.wikidata.org/entity/Q8407'), ('sname', '1952 Summer Olympics')]
# [('s', 'http://www.wikidata.org/entity/Q8411'), ('sname', '1956 Summer Olympics')]
# [('s', 'http://www.wikidata.org/entity/Q8450'), ('sname', '1980 Summer Olympics')]
# [('s', 'http://www.wikidata.org/entity/Q8456'), ('sname', '1984 Summer Olympics')]
# [('s', 'http://www.wikidata.org/entity/Q8080'), ('sname', '1896 Summer Olympics')]
# [('s', 'http://www.wikidata.org/entity/Q8403'), ('sname', '1948 Summer Olympics')]
# [('s', 'http://www.wikidata.org/entity/Q8105'), ('sname', '1906 Intercalated Games')]
# [('s', 'http://www.wikidata.org/entity/Q8123'), ('sname', '1916 Summer Olympics')]
# [('s', 'http://www.wikidata.org/entity/Q1451505'), ('sname', '2028 Summer Olympics')]
# [('s', 'http://www.wikidata.org/entity/Q31039462'), ('sname', '2032 Summer Olympics')]
# [('s', 'http://www.wikidata.org/entity/Q995653'), ('sname', '2024 Summer Olympics')]
# [('s', 'http://www.wikidata.org/entity/Q8368'), ('sname', '1940 Summer Olympics')]
# [('s', 'http://www.wikidata.org/entity/Q8376'), ('sname', '1944 Summer Olympics')]
# [('s', 'http://www.wikidata.org/entity/Q108045332'), ('sname', '2036 Summer Olympics')]
# 37

# %%
# aim: get the properties related to 'Summer Olympic Games 2004'
# result: the properties related to 'Summer Olympic Games 2004'
queryString = """
SELECT DISTINCT ?p ?name
WHERE {
   # bind something
   # ?s ?p wd:Q8558 .
   # get the label
   # ?p sc:name ?name .
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P6291'), ('name', 'advertises')]
# [('p', 'http://www.wikidata.org/prop/direct/P101'), ('name', 'field of work')]
# [('p', 'http://www.wikidata.org/prop/direct/P1269'), ('name', 'facet of')]
# [('p', 'http://www.wikidata.org/prop/direct/P1344'), ('name', 'participant in')]
# [('p', 'http://www.wikidata.org/prop/direct/P155'), ('name', 'follows')]
# [('p', 'http://www.wikidata.org/prop/direct/P156'), ('name', 'followed by')]
# [('p', 'http://www.wikidata.org/prop/direct/P301'), ('name', "category's main topic")]
# [('p', 'http://www.wikidata.org/prop/direct/P361'), ('name', 'part of')]
# [('p', 'http://www.wikidata.org/prop/direct/P466'), ('name', 'occupant')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('name', 'has part')]
# [('p', 'http://www.wikidata.org/prop/direct/P793'), ('name', 'significant event')]
# [('p', 'http://www.wikidata.org/prop/direct/P971'), ('name', 'category combines topics')]
# 12

# %%
# aim: get all subjects that are related to 'Summer Olympic Games 2004' through 'part of', 'significant event' and 'has part'
# result: we found 'athletics at the 2004 Summer Olympics'
queryString = """
SELECT DISTINCT ?s ?name ?p
WHERE {
   # bind something
   # ?s ?p wd:Q8558 .
   # get the label
   # ?s sc:name ?name .
   FILTER (?p IN (wdt:P361,wdt:P527,wdt:P793))
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('s', 'http://www.wikidata.org/entity/Q1322006'), ('name', '2004 Summer Olympics torch relay'), ('p', 'http://www.wikidata.org/prop/direct/P361')]
# [('s', 'http://www.wikidata.org/entity/Q118446'), ('name', 'rowing at the 2004 Summer Olympics'), ('p', 'http://www.wikidata.org/prop/direct/P361')]
# [('s', 'http://www.wikidata.org/entity/Q15637418'), ('name', 'artistic gymnastics at the 2004 Summer Olympics'), ('p', 'http://www.wikidata.org/prop/direct/P361')]
# [('s', 'http://www.wikidata.org/entity/Q159821'), ('name', 'Summer Olympic Games'), ('p', 'http://www.wikidata.org/prop/direct/P527')]
# [('s', 'http://www.wikidata.org/entity/Q1602350'), ('name', 'rhythmic gymnastics at the 2004 Summer Olympics'), ('p', 'http://www.wikidata.org/prop/direct/P361')]
# [('s', 'http://www.wikidata.org/entity/Q2022374'), ('name', 'trampoline gymnastics at the 2004 Summer Olympics'), ('p', 'http://www.wikidata.org/prop/direct/P361')]
# [('s', 'http://www.wikidata.org/entity/Q220886'), ('name', 'swimming at the 2004 Summer Olympics'), ('p', 'http://www.wikidata.org/prop/direct/P361')]
# [('s', 'http://www.wikidata.org/entity/Q262255'), ('name', 'taekwondo at the 2004 Summer Olympics'), ('p', 'http://www.wikidata.org/prop/direct/P361')]
# [('s', 'http://www.wikidata.org/entity/Q263332'), ('name', 'gymnastics at the 2004 Summer Olympics'), ('p', 'http://www.wikidata.org/prop/direct/P361')]
# [('s', 'http://www.wikidata.org/entity/Q286270'), ('name', 'judo at the 2004 Summer Olympics'), ('p', 'http://www.wikidata.org/prop/direct/P361')]
# [('s', 'http://www.wikidata.org/entity/Q339283'), ('name', 'athletics at the 2004 Summer Olympics'), ('p', 'http://www.wikidata.org/prop/direct/P361')]
# [('s', 'http://www.wikidata.org/entity/Q371708'), ('name', 'football at the 2004 Summer Olympics'), ('p', 'http://www.wikidata.org/prop/direct/P361')]
# [('s', 'http://www.wikidata.org/entity/Q389836'), ('name', 'synchronized swimming at the 2004 Summer Olympics'), ('p', 'http://www.wikidata.org/prop/direct/P361')]
# [('s', 'http://www.wikidata.org/entity/Q509941'), ('name', 'triathlon at the 2004 Summer Olympics'), ('p', 'http://www.wikidata.org/prop/direct/P361')]
# [('s', 'http://www.wikidata.org/entity/Q538706'), ('name', 'table tennis at the 2004 Summer Olympics'), ('p', 'http://www.wikidata.org/prop/direct/P361')]
# [('s', 'http://www.wikidata.org/entity/Q575675'), ('name', 'archery at the 2004 Summer Olympics'), ('p', 'http://www.wikidata.org/prop/direct/P361')]
# [('s', 'http://www.wikidata.org/entity/Q576646'), ('name', 'shooting at the 2004 Summer Olympics'), ('p', 'http://www.wikidata.org/prop/direct/P361')]
# [('s', 'http://www.wikidata.org/entity/Q579800'), ('name', 'fencing at the 2004 Summer Olympics'), ('p', 'http://www.wikidata.org/prop/direct/P361')]
# [('s', 'http://www.wikidata.org/entity/Q579834'), ('name', 'sailing at the 2004 Summer Olympics'), ('p', 'http://www.wikidata.org/prop/direct/P361')]
# [('s', 'http://www.wikidata.org/entity/Q608968'), ('name', 'baseball at the 2004 Summer Olympics'), ('p', 'http://www.wikidata.org/prop/direct/P361')]
# [('s', 'http://www.wikidata.org/entity/Q657019'), ('name', 'handball at the 2004 Summer Olympics'), ('p', 'http://www.wikidata.org/prop/direct/P361')]
# [('s', 'http://www.wikidata.org/entity/Q661627'), ('name', 'badminton at the 2004 Summer Olympics'), ('p', 'http://www.wikidata.org/prop/direct/P361')]
# [('s', 'http://www.wikidata.org/entity/Q679320'), ('name', 'modern pentathlon at the 2004 Summer Olympics'), ('p', 'http://www.wikidata.org/prop/direct/P361')]
# [('s', 'http://www.wikidata.org/entity/Q723649'), ('name', 'volleyball at the 2004 Summer Olympics'), ('p', 'http://www.wikidata.org/prop/direct/P361')]
# [('s', 'http://www.wikidata.org/entity/Q733387'), ('name', 'tennis at the 2004 Summer Olympics'), ('p', 'http://www.wikidata.org/prop/direct/P361')]
# [('s', 'http://www.wikidata.org/entity/Q748672'), ('name', 'water polo at the 2004 Summer Olympics'), ('p', 'http://www.wikidata.org/prop/direct/P361')]
# [('s', 'http://www.wikidata.org/entity/Q748707'), ('name', 'weightlifting at the 2004 Summer Olympics'), ('p', 'http://www.wikidata.org/prop/direct/P361')]
# [('s', 'http://www.wikidata.org/entity/Q748752'), ('name', 'boxing at the 2004 Summer Olympics'), ('p', 'http://www.wikidata.org/prop/direct/P361')]
# [('s', 'http://www.wikidata.org/entity/Q754572'), ('name', 'field hockey at the 2004 Summer Olympics'), ('p', 'http://www.wikidata.org/prop/direct/P361')]
# [('s', 'http://www.wikidata.org/entity/Q754598'), ('name', 'wrestling at the 2004 Summer Olympics'), ('p', 'http://www.wikidata.org/prop/direct/P361')]
# [('s', 'http://www.wikidata.org/entity/Q756112'), ('name', 'diving at the 2004 Summer Olympics'), ('p', 'http://www.wikidata.org/prop/direct/P361')]
# [('s', 'http://www.wikidata.org/entity/Q7992120'), ('name', 'wheelchair racing at the 2004 Summer Olympics'), ('p', 'http://www.wikidata.org/prop/direct/P361')]
# [('s', 'http://www.wikidata.org/entity/Q82035'), ('name', 'basketball at the 2004 Summer Olympics'), ('p', 'http://www.wikidata.org/prop/direct/P361')]
# [('s', 'http://www.wikidata.org/entity/Q833279'), ('name', 'cycling at the 2004 Summer Olympics'), ('p', 'http://www.wikidata.org/prop/direct/P361')]
# [('s', 'http://www.wikidata.org/entity/Q833745'), ('name', 'softball at the 2004 Summer Olympics'), ('p', 'http://www.wikidata.org/prop/direct/P361')]
# [('s', 'http://www.wikidata.org/entity/Q838622'), ('name', 'canoeing at the 2004 Summer Olympics'), ('p', 'http://www.wikidata.org/prop/direct/P361')]
# [('s', 'http://www.wikidata.org/entity/Q843718'), ('name', 'equestrian at the 2004 Summer Olympics'), ('p', 'http://www.wikidata.org/prop/direct/P361')]
# [('s', 'http://www.wikidata.org/entity/Q946459'), ('name', 'beach volleyball at the 2004 Summer Olympics'), ('p', 'http://www.wikidata.org/prop/direct/P361')]
# [('s', 'http://www.wikidata.org/entity/Q4867703'), ('name', "Basketball at the 2004 Summer Olympics – Women's team squads"), ('p', 'http://www.wikidata.org/prop/direct/P361')]
# [('s', 'http://www.wikidata.org/entity/Q16210616'), ('name', 'Li Qingnian'), ('p', 'http://www.wikidata.org/prop/direct/P793')]
# [('s', 'http://www.wikidata.org/entity/Q2025033'), ('name', "Handball at the 2004 Summer Olympics – Women's team squads"), ('p', 'http://www.wikidata.org/prop/direct/P361')]
# [('s', 'http://www.wikidata.org/entity/Q7973655'), ('name', "Water polo at the 2004 Summer Olympics – Men's team rosters"), ('p', 'http://www.wikidata.org/prop/direct/P361')]
# [('s', 'http://www.wikidata.org/entity/Q7973656'), ('name', "Water polo at the 2004 Summer Olympics – Women's team rosters"), ('p', 'http://www.wikidata.org/prop/direct/P361')]
# [('s', 'http://www.wikidata.org/entity/Q3567610'), ('name', '2004 Summer Olympics opening ceremony'), ('p', 'http://www.wikidata.org/prop/direct/P361')]
# [('s', 'http://www.wikidata.org/entity/Q1071899'), ('name', "Football at the 2004 Summer Olympics – Men's team squads"), ('p', 'http://www.wikidata.org/prop/direct/P361')]
# 45

# %%
# aim: get all the properties related to 'athletics at the 2004 Summer Olympics'
# result: all the properties related to 'athletics at the 2004 Summer Olympics'
queryString = """
SELECT DISTINCT ?p ?name 
WHERE {
   # bind something
   # ?s ?p wd:Q339283 .
   # get the label
   # ?p sc:name ?name .
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P1423'), ('name', 'template has topic')]
# [('p', 'http://www.wikidata.org/prop/direct/P1344'), ('name', 'participant in')]
# [('p', 'http://www.wikidata.org/prop/direct/P155'), ('name', 'follows')]
# [('p', 'http://www.wikidata.org/prop/direct/P301'), ('name', "category's main topic")]
# [('p', 'http://www.wikidata.org/prop/direct/P361'), ('name', 'part of')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('name', 'has part')]
# 6

# %%
# aim: get all the subjects related with 'athletics at the 2004 Summer Olympics' through 'part of' and 'has part'
# result: we found 'athletics at the 2004 Summer Olympics – women's marathon' and 'athletics at the 2004 Summer Olympics – men's marathon'
queryString = """
SELECT DISTINCT ?s ?name ?p 
WHERE {
   # bind something
   # ?s ?p wd:Q339283 .
   # get the label
   # ?s sc:name ?name .
   FILTER (?p IN (wdt:P361,wdt:P527))
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('s', 'http://www.wikidata.org/entity/Q1433109'), ('name', "athletics at the 2004 Summer Olympics – men's pole vault"), ('p', 'http://www.wikidata.org/prop/direct/P361')]
# [('s', 'http://www.wikidata.org/entity/Q3628756'), ('name', "athletics at the 2004 Summer Olympics – women's 4 × 400 metres relay"), ('p', 'http://www.wikidata.org/prop/direct/P361')]
# [('s', 'http://www.wikidata.org/entity/Q1439323'), ('name', "athletics at the 2004 Summer Olympics – women's javelin throw"), ('p', 'http://www.wikidata.org/prop/direct/P361')]
# [('s', 'http://www.wikidata.org/entity/Q8558'), ('name', '2004 Summer Olympics'), ('p', 'http://www.wikidata.org/prop/direct/P527')]
# [('s', 'http://www.wikidata.org/entity/Q2313564'), ('name', "athletics at the 2004 Summer Olympics – men's 200 metres"), ('p', 'http://www.wikidata.org/prop/direct/P361')]
# [('s', 'http://www.wikidata.org/entity/Q1433079'), ('name', "athletics at the 2004 Summer Olympics – women's long jump"), ('p', 'http://www.wikidata.org/prop/direct/P361')]
# [('s', 'http://www.wikidata.org/entity/Q2558493'), ('name', "athletics at the 2004 Summer Olympics – women's triple jump"), ('p', 'http://www.wikidata.org/prop/direct/P361')]
# [('s', 'http://www.wikidata.org/entity/Q1439338'), ('name', "athletics at the 2004 Summer Olympics – women's 200 metres"), ('p', 'http://www.wikidata.org/prop/direct/P361')]
# [('s', 'http://www.wikidata.org/entity/Q2313481'), ('name', "athletics at the 2004 Summer Olympics – women's 100 metres"), ('p', 'http://www.wikidata.org/prop/direct/P361')]
# [('s', 'http://www.wikidata.org/entity/Q220855'), ('name', "athletics at the 2004 Summer Olympics – men's 100 metres"), ('p', 'http://www.wikidata.org/prop/direct/P361')]
# [('s', 'http://www.wikidata.org/entity/Q2634499'), ('name', "athletics at the 2004 Summer Olympics – men's 10,000 metres"), ('p', 'http://www.wikidata.org/prop/direct/P361')]
# [('s', 'http://www.wikidata.org/entity/Q2463752'), ('name', "athletics at the 2004 Summer Olympics – men's 400 metres"), ('p', 'http://www.wikidata.org/prop/direct/P361')]
# [('s', 'http://www.wikidata.org/entity/Q1439249'), ('name', "athletics at the 2004 Summer Olympics – men's 110 metres hurdles"), ('p', 'http://www.wikidata.org/prop/direct/P361')]
# [('s', 'http://www.wikidata.org/entity/Q3628754'), ('name', "athletics at the 2004 Summer Olympics – men's 4 × 100 metres relay"), ('p', 'http://www.wikidata.org/prop/direct/P361')]
# [('s', 'http://www.wikidata.org/entity/Q1439291'), ('name', "athletics at the 2004 Summer Olympics – men's 5000 metres"), ('p', 'http://www.wikidata.org/prop/direct/P361')]
# [('s', 'http://www.wikidata.org/entity/Q1433072'), ('name', "athletics at the 2004 Summer Olympics – men's discus throw"), ('p', 'http://www.wikidata.org/prop/direct/P361')]
# [('s', 'http://www.wikidata.org/entity/Q2313443'), ('name', "athletics at the 2004 Summer Olympics – women's 10,000 metres"), ('p', 'http://www.wikidata.org/prop/direct/P361')]
# [('s', 'http://www.wikidata.org/entity/Q582514'), ('name', "athletics at the 2004 Summer Olympics – men's decathlon"), ('p', 'http://www.wikidata.org/prop/direct/P361')]
# [('s', 'http://www.wikidata.org/entity/Q1439276'), ('name', "athletics at the 2004 Summer Olympics – men's javelin throw"), ('p', 'http://www.wikidata.org/prop/direct/P361')]
# [('s', 'http://www.wikidata.org/entity/Q2557141'), ('name', "athletics at the 2004 Summer Olympics – men's 3000 metres steeplechase"), ('p', 'http://www.wikidata.org/prop/direct/P361')]
# [('s', 'http://www.wikidata.org/entity/Q2557129'), ('name', "athletics at the 2004 Summer Olympics – women's 800 metres"), ('p', 'http://www.wikidata.org/prop/direct/P361')]
# [('s', 'http://www.wikidata.org/entity/Q2318836'), ('name', "athletics at the 2004 Summer Olympics – women's 20 kilometres walk"), ('p', 'http://www.wikidata.org/prop/direct/P361')]
# [('s', 'http://www.wikidata.org/entity/Q936622'), ('name', "athletics at the 2004 Summer Olympics – men's 20 kilometres walk"), ('p', 'http://www.wikidata.org/prop/direct/P361')]
# [('s', 'http://www.wikidata.org/entity/Q2201769'), ('name', "athletics at the 2004 Summer Olympics – men's long jump"), ('p', 'http://www.wikidata.org/prop/direct/P361')]
# [('s', 'http://www.wikidata.org/entity/Q2552272'), ('name', "athletics at the 2004 Summer Olympics – women's marathon"), ('p', 'http://www.wikidata.org/prop/direct/P361')]
# [('s', 'http://www.wikidata.org/entity/Q3628752'), ('name', "athletics at the 2004 Summer Olympics – women's 400 metres hurdles"), ('p', 'http://www.wikidata.org/prop/direct/P361')]
# [('s', 'http://www.wikidata.org/entity/Q3628755'), ('name', "athletics at the 2004 Summer Olympics – women's 4 × 100 metres relay"), ('p', 'http://www.wikidata.org/prop/direct/P361')]
# [('s', 'http://www.wikidata.org/entity/Q2312004'), ('name', "athletics at the 2004 Summer Olympics – women's high jump"), ('p', 'http://www.wikidata.org/prop/direct/P361')]
# [('s', 'http://www.wikidata.org/entity/Q2198226'), ('name', "athletics at the 2004 Summer Olympics – men's triple jump"), ('p', 'http://www.wikidata.org/prop/direct/P361')]
# [('s', 'http://www.wikidata.org/entity/Q2723756'), ('name', "athletics at the 2004 Summer Olympics – women's 5000 metres"), ('p', 'http://www.wikidata.org/prop/direct/P361')]
# [('s', 'http://www.wikidata.org/entity/Q1440658'), ('name', "athletics at the 2004 Summer Olympics – women's discus throw"), ('p', 'http://www.wikidata.org/prop/direct/P361')]
# [('s', 'http://www.wikidata.org/entity/Q2558525'), ('name', "athletics at the 2004 Summer Olympics – women's heptathlon"), ('p', 'http://www.wikidata.org/prop/direct/P361')]
# [('s', 'http://www.wikidata.org/entity/Q3628757'), ('name', "athletics at the 2004 Summer Olympics – men's 4 × 400 metres relay"), ('p', 'http://www.wikidata.org/prop/direct/P361')]
# [('s', 'http://www.wikidata.org/entity/Q2313552'), ('name', "athletics at the 2004 Summer Olympics – women's 1500 metres"), ('p', 'http://www.wikidata.org/prop/direct/P361')]
# [('s', 'http://www.wikidata.org/entity/Q1110152'), ('name', "athletics at the 2004 Summer Olympics – women's 100 metres hurdles"), ('p', 'http://www.wikidata.org/prop/direct/P361')]
# [('s', 'http://www.wikidata.org/entity/Q613746'), ('name', "athletics at the 2004 Summer Olympics – women's shot put"), ('p', 'http://www.wikidata.org/prop/direct/P361')]
# [('s', 'http://www.wikidata.org/entity/Q2557677'), ('name', "athletics at the 2004 Summer Olympics – women's pole vault"), ('p', 'http://www.wikidata.org/prop/direct/P361')]
# [('s', 'http://www.wikidata.org/entity/Q900405'), ('name', "athletics at the 2004 Summer Olympics – men's 50 kilometres walk"), ('p', 'http://www.wikidata.org/prop/direct/P361')]
# [('s', 'http://www.wikidata.org/entity/Q2318914'), ('name', "athletics at the 2004 Summer Olympics – women's hammer throw"), ('p', 'http://www.wikidata.org/prop/direct/P361')]
# [('s', 'http://www.wikidata.org/entity/Q2558983'), ('name', "athletics at the 2004 Summer Olympics – men's 1500 metres"), ('p', 'http://www.wikidata.org/prop/direct/P361')]
# [('s', 'http://www.wikidata.org/entity/Q2312939'), ('name', "athletics at the 2004 Summer Olympics – men's 800 metres"), ('p', 'http://www.wikidata.org/prop/direct/P361')]
# [('s', 'http://www.wikidata.org/entity/Q2724464'), ('name', "athletics at the 2004 Summer Olympics – men's high jump"), ('p', 'http://www.wikidata.org/prop/direct/P361')]
# [('s', 'http://www.wikidata.org/entity/Q1433269'), ('name', "athletics at the 2004 Summer Olympics – men's 400 metres hurdles"), ('p', 'http://www.wikidata.org/prop/direct/P361')]
# [('s', 'http://www.wikidata.org/entity/Q1433101'), ('name', "athletics at the 2004 Summer Olympics – men's shot put"), ('p', 'http://www.wikidata.org/prop/direct/P361')]
# [('s', 'http://www.wikidata.org/entity/Q2313511'), ('name', "athletics at the 2004 Summer Olympics – women's 400 metres"), ('p', 'http://www.wikidata.org/prop/direct/P361')]
# [('s', 'http://www.wikidata.org/entity/Q2443986'), ('name', "athletics at the 2004 Summer Olympics – men's marathon"), ('p', 'http://www.wikidata.org/prop/direct/P361')]
# [('s', 'http://www.wikidata.org/entity/Q2311975'), ('name', "athletics at the 2004 Summer Olympics – men's hammer throw"), ('p', 'http://www.wikidata.org/prop/direct/P361')]
# 47

# %%
# aim: get all the subjects related with 'athletics at the 2004 Summer Olympics' through 'part of' and 'has part'
# result: we found 'athletics at the 2004 Summer Olympics – women's marathon' and 'athletics at the 2004 Summer Olympics – men's marathon'
queryString = """
SELECT DISTINCT ?p ?name
WHERE {
   # bind something
   # ?s ?p ?o .
   # get the label
   # ?p sc:name ?name .
   FILTER (?s IN (wd:Q2443986,wd:Q2552272))
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P1132'), ('name', 'number of participants')]
# [('p', 'http://www.wikidata.org/prop/direct/P1346'), ('name', 'winner')]
# [('p', 'http://www.wikidata.org/prop/direct/P155'), ('name', 'follows')]
# [('p', 'http://www.wikidata.org/prop/direct/P156'), ('name', 'followed by')]
# [('p', 'http://www.wikidata.org/prop/direct/P17'), ('name', 'country')]
# [('p', 'http://www.wikidata.org/prop/direct/P18'), ('name', 'image')]
# [('p', 'http://www.wikidata.org/prop/direct/P2094'), ('name', 'competition class')]
# [('p', 'http://www.wikidata.org/prop/direct/P276'), ('name', 'location')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('name', 'instance of')]
# [('p', 'http://www.wikidata.org/prop/direct/P361'), ('name', 'part of')]
# [('p', 'http://www.wikidata.org/prop/direct/P580'), ('name', 'start time')]
# [('p', 'http://www.wikidata.org/prop/direct/P585'), ('name', 'point in time')]
# [('p', 'http://www.wikidata.org/prop/direct/P641'), ('name', 'sport')]
# [('p', 'http://www.wikidata.org/prop/direct/P646'), ('name', 'Freebase ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P664'), ('name', 'organizer')]
# [('p', 'http://www.wikidata.org/prop/direct/P9055'), ('name', 'Olympedia event ID')]
# 16

# %%
# aim: get all the properties related with 'athletics at the 2004 Summer Olympics – women's marathon' and 'athletics at the 2004 Summer Olympics – men's marathon'
# result: we found 'participant in'
queryString = """
SELECT DISTINCT ?p ?name
WHERE {
   # bind something
   # ?s ?p ?o .
   # get the label
   # ?p sc:name ?name .
   FILTER (?o IN (wd:Q2443986,wd:Q2552272))
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P1344'), ('name', 'participant in')]
# [('p', 'http://www.wikidata.org/prop/direct/P155'), ('name', 'follows')]
# [('p', 'http://www.wikidata.org/prop/direct/P156'), ('name', 'followed by')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('name', 'has part')]
# 4

# %%
# aim: get all the athletes who were 'participant in' the 'athletics at the 2004 Summer Olympics – women's marathon' and 'athletics at the 2004 Summer Olympics – men's marathon'
# result: we found just 2 athletes... Now we read the task again, maybe we are required to find only the people who are 'marathon runner' as 'occupation' and who 'participated in' the 
#         Summer Olympic games... 
queryString = """
SELECT DISTINCT ?s ?name
WHERE {
   # bind something
   # ?s wdt:P1344 ?o .
   # get the label
   # ?s sc:name ?name .
   FILTER (?o IN (wd:Q2443986,wd:Q2552272))
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('s', 'http://www.wikidata.org/entity/Q2271929'), ('name', 'Bat-Ochiryn Ser-Od')]
# [('s', 'http://www.wikidata.org/entity/Q1617873'), ('name', 'Marcel Matanin')]
# 2

# %%
# aim: get all the athletes who were 'participant in' the 'athletics at the 2004 Summer Olympics – women's marathon' and 'athletics at the 2004 Summer Olympics – men's marathon'
# result: we found just 2 athletes... Now we read the task again, maybe we are required to find only the people who are 'marathon runner' as 'occupation' and who 'participated in' the 
#         Summer Olympic games... 
queryString = """
SELECT DISTINCT ?o ?name
WHERE {
   # bind something
   wd:Q2271929 wdt:P1344 ?o .
   # get the label
   # ?o sc:name ?name .
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('o', 'http://www.wikidata.org/entity/Q18193712'), ('name', 'athletics at the 2016 Summer Olympics')]
# [('o', 'http://www.wikidata.org/entity/Q3287514'), ('name', "2007 World Championships in Athletics – Men's Marathon")]
# [('o', 'http://www.wikidata.org/entity/Q3702617'), ('name', "2003 World Championships in Athletics – Men's Marathon")]
# [('o', 'http://www.wikidata.org/entity/Q4605105'), ('name', "2005 World Championships in Athletics – Men's Marathon")]
# [('o', 'http://www.wikidata.org/entity/Q20312969'), ('name', "athletics at the 2014 Asian Games – men's marathon")]
# [('o', 'http://www.wikidata.org/entity/Q285408'), ('name', '2002 IAAF World Half Marathon Championships')]
# [('o', 'http://www.wikidata.org/entity/Q21858018'), ('name', "athletics at the 2016 Summer Olympics – men's marathon")]
# [('o', 'http://www.wikidata.org/entity/Q20804554'), ('name', "2015 World Championships in Athletics – men's marathon")]
# [('o', 'http://www.wikidata.org/entity/Q1553760'), ('name', '2005 IAAF World Half Marathon Championships')]
# [('o', 'http://www.wikidata.org/entity/Q693595'), ('name', "athletics at the 2008 Summer Olympics – men's marathon")]
# [('o', 'http://www.wikidata.org/entity/Q2503611'), ('name', "2009 World Championships in Athletics – Men's Marathon")]
# [('o', 'http://www.wikidata.org/entity/Q14524166'), ('name', "2013 World Championships in Athletics – Men's Marathon")]
# [('o', 'http://www.wikidata.org/entity/Q2029885'), ('name', "2011 World Championships in Athletics – Men's Marathon")]
# [('o', 'http://www.wikidata.org/entity/Q16962226'), ('name', 'Asian Marathon Championship')]
# [('o', 'http://www.wikidata.org/entity/Q4613223'), ('name', "2009 Asian Athletics Championships – men's 10,000 metres")]
# [('o', 'http://www.wikidata.org/entity/Q15054663'), ('name', 'athletics at the 2013 East Asian Games')]
# [('o', 'http://www.wikidata.org/entity/Q1798983'), ('name', "athletics at the 2012 Summer Olympics – men's marathon")]
# [('o', 'http://www.wikidata.org/entity/Q2443986'), ('name', "athletics at the 2004 Summer Olympics – men's marathon")]
# [('o', 'http://www.wikidata.org/entity/Q4814536'), ('name', "athletics at the 2006 Asian Games – men's marathon")]
# [('o', 'http://www.wikidata.org/entity/Q4613233'), ('name', "2009 Asian Athletics Championships – men's 5000 metres")]
# 20

# %%
# aim: try to find if there exist subjects that are 'instance of' 'Olympic Games'
# result: we found 'Summer Olympic Games 2004','Summer Olympic Games 2008',... We should investigate about the marathons of these years
queryString = """
SELECT DISTINCT ?o ?sname
WHERE {
   # bind something
   wd:Q2271929 wdt:P106 ?o.
   # get the label
   # ?o sc:name ?sname .
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('o', 'http://www.wikidata.org/entity/Q13382460'), ('sname', 'marathon runner')]
# [('o', 'http://www.wikidata.org/entity/Q11513337'), ('sname', 'athletics competitor')]
# 2

# %%
# aim: find all the people that are 'marathon runner' as 'occupation'
# result: we found 'Summer Olympic Games 2004','Summer Olympic Games 2008',... We should investigate about the marathons of these years
queryString = """
SELECT DISTINCT ?s ?sname
WHERE {
   # bind something
   # ?s wdt:P106 wd:Q13382460.
   # get the label
   # ?s sc:name ?sname .
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('s', 'http://www.wikidata.org/entity/Q1701191'), ('sname', 'John Nada Saya')]
# [('s', 'http://www.wikidata.org/entity/Q16006623'), ('sname', 'Harry Payne')]
# [('s', 'http://www.wikidata.org/entity/Q16007889'), ('sname', 'John Tarrant')]
# [('s', 'http://www.wikidata.org/entity/Q16008400'), ('sname', 'Waldemar Karlsson')]
# [('s', 'http://www.wikidata.org/entity/Q16011969'), ('sname', 'John J. Reynolds')]
# [('s', 'http://www.wikidata.org/entity/Q1602744'), ('sname', 'Hellen Mugo')]
# [('s', 'http://www.wikidata.org/entity/Q16185418'), ('sname', 'Jerry Kiernan')]
# [('s', 'http://www.wikidata.org/entity/Q16186777'), ('sname', 'George Malley')]
# [('s', 'http://www.wikidata.org/entity/Q16210841'), ('sname', 'Elva Dryer')]
# [('s', 'http://www.wikidata.org/entity/Q16212704'), ('sname', 'José Alejandro Semprún')]
# [('s', 'http://www.wikidata.org/entity/Q16226788'), ('sname', 'Jacob Bragg')]
# [('s', 'http://www.wikidata.org/entity/Q17010986'), ('sname', 'Naomi Sakashita')]
# [('s', 'http://www.wikidata.org/entity/Q1666324'), ('sname', 'Stephen Kosgei Kibet')]
# [('s', 'http://www.wikidata.org/entity/Q275831'), ('sname', 'Christelle Daunay')]
# [('s', 'http://www.wikidata.org/entity/Q18129162'), ('sname', 'Steve Way')]
# [('s', 'http://www.wikidata.org/entity/Q3575181'), ('sname', 'Zemzem Ahmed')]
# [('s', 'http://www.wikidata.org/entity/Q20966604'), ('sname', 'Eric Ndiema')]
# [('s', 'http://www.wikidata.org/entity/Q20979480'), ('sname', 'Andy Robertson')]
# [('s', 'http://www.wikidata.org/entity/Q20982761'), ('sname', 'Alina Prokopyeva')]
# [('s', 'http://www.wikidata.org/entity/Q20988044'), ('sname', 'Heather Lieberg')]
# [('s', 'http://www.wikidata.org/entity/Q20988053'), ('sname', 'Gulzhanat Zhanatbek')]
# [('s', 'http://www.wikidata.org/entity/Q20988442'), ('sname', 'Ian Burrell')]
# [('s', 'http://www.wikidata.org/entity/Q27070232'), ('sname', 'Michele Fanelli')]
# [('s', 'http://www.wikidata.org/entity/Q435068'), ('sname', 'Alain Mimoun')]
# [('s', 'http://www.wikidata.org/entity/Q435784'), ('sname', 'Stine Larsen')]
# [('s', 'http://www.wikidata.org/entity/Q436062'), ('sname', 'Billy Mills')]
# [('s', 'http://www.wikidata.org/entity/Q450131'), ('sname', 'Shigeru So')]
# [('s', 'http://www.wikidata.org/entity/Q450136'), ('sname', 'Takeshi So')]
# [('s', 'http://www.wikidata.org/entity/Q450367'), ('sname', 'Alyson Dixon')]
# [('s', 'http://www.wikidata.org/entity/Q456420'), ('sname', 'Philes Ongori')]
# [('s', 'http://www.wikidata.org/entity/Q505737'), ('sname', 'Juan Carlos Zabala')]
# [('s', 'http://www.wikidata.org/entity/Q533551'), ('sname', 'Peninah Arusei')]
# [('s', 'http://www.wikidata.org/entity/Q535100'), ('sname', 'Joyce Smith')]
# [('s', 'http://www.wikidata.org/entity/Q536251'), ('sname', 'Hellen Jemaiyo Kimutai')]
# [('s', 'http://www.wikidata.org/entity/Q551925'), ('sname', 'Tariku Jufar')]
# [('s', 'http://www.wikidata.org/entity/Q1735701'), ('sname', "Kate O'Neill")]
# [('s', 'http://www.wikidata.org/entity/Q1741489'), ('sname', 'Kim Eun-jeong')]
# [('s', 'http://www.wikidata.org/entity/Q1761766'), ('sname', 'Lewis Tewanima')]
# [('s', 'http://www.wikidata.org/entity/Q1819023'), ('sname', 'Leonard Mucheru Maina')]
# [('s', 'http://www.wikidata.org/entity/Q1845306'), ('sname', 'John Burra')]
# [('s', 'http://www.wikidata.org/entity/Q1850509'), ('sname', 'Hendricus Wessel')]
# [('s', 'http://www.wikidata.org/entity/Q1866774'), ('sname', 'Lyudmila Petrova')]
# [('s', 'http://www.wikidata.org/entity/Q261792'), ('sname', 'Liz McColgan')]
# [('s', 'http://www.wikidata.org/entity/Q286940'), ('sname', 'Brendan Foster')]
# [('s', 'http://www.wikidata.org/entity/Q434105'), ('sname', 'Steve Cram')]
# [('s', 'http://www.wikidata.org/entity/Q2748165'), ('sname', 'Christiaan Huijgens')]
# [('s', 'http://www.wikidata.org/entity/Q5080889'), ('sname', 'Charles Melis')]
# [('s', 'http://www.wikidata.org/entity/Q5103998'), ('sname', 'Choi Yun-chil')]
# [('s', 'http://www.wikidata.org/entity/Q19845638'), ('sname', 'María del Carmen Cárdenas')]
# [('s', 'http://www.wikidata.org/entity/Q94362'), ('sname', 'Romeo Bertini')]
# [('s', 'http://www.wikidata.org/entity/Q168495'), ('sname', 'Boughera El Ouafi')]
# [('s', 'http://www.wikidata.org/entity/Q192033'), ('sname', 'Zersenay Tadese')]
# [('s', 'http://www.wikidata.org/entity/Q218486'), ('sname', 'Zola Budd')]
# [('s', 'http://www.wikidata.org/entity/Q256770'), ('sname', 'Ingrid Kristiansen')]
# [('s', 'http://www.wikidata.org/entity/Q260677'), ('sname', 'Elana Meyer')]
# [('s', 'http://www.wikidata.org/entity/Q260978'), ('sname', 'Berhane Adere')]
# [('s', 'http://www.wikidata.org/entity/Q271607'), ('sname', 'Alina Ivanova')]
# [('s', 'http://www.wikidata.org/entity/Q301144'), ('sname', 'Roberto Barbi')]
# [('s', 'http://www.wikidata.org/entity/Q345711'), ('sname', 'Driss El Himer')]
# [('s', 'http://www.wikidata.org/entity/Q359080'), ('sname', 'Albin Lermusiaux')]
# [('s', 'http://www.wikidata.org/entity/Q360703'), ('sname', 'Mike Ryan')]
# [('s', 'http://www.wikidata.org/entity/Q433194'), ('sname', 'Chen Rong')]
# [('s', 'http://www.wikidata.org/entity/Q1520131'), ('sname', 'Getuli Bayo')]
# [('s', 'http://www.wikidata.org/entity/Q459795'), ('sname', 'Nicholas Chelimo')]
# [('s', 'http://www.wikidata.org/entity/Q471602'), ('sname', 'Viktor Röthlin')]
# [('s', 'http://www.wikidata.org/entity/Q472410'), ('sname', 'Luís Novo')]
# [('s', 'http://www.wikidata.org/entity/Q473665'), ('sname', 'Zebedayo Bayo')]
# [('s', 'http://www.wikidata.org/entity/Q482890'), ('sname', 'Ana Kuzmanović')]
# [('s', 'http://www.wikidata.org/entity/Q510629'), ('sname', 'Jemima Sumgong')]
# [('s', 'http://www.wikidata.org/entity/Q517647'), ('sname', 'Charlotte Purdue')]
# [('s', 'http://www.wikidata.org/entity/Q675652'), ('sname', 'Günther Weidlinger')]
# [('s', 'http://www.wikidata.org/entity/Q677179'), ('sname', 'Chung Yun-Hee')]
# [('s', 'http://www.wikidata.org/entity/Q1917368'), ('sname', 'Mehmet Yurdadön')]
# [('s', 'http://www.wikidata.org/entity/Q1949191'), ('sname', 'Moses Masai')]
# [('s', 'http://www.wikidata.org/entity/Q5125212'), ('sname', 'Claire Hallissey')]
# [('s', 'http://www.wikidata.org/entity/Q5274619'), ('sname', 'Diego Colorado')]
# [('s', 'http://www.wikidata.org/entity/Q5285654'), ('sname', 'Dmitriy Burmakin')]
# [('s', 'http://www.wikidata.org/entity/Q9286627'), ('sname', 'Harry Smith')]
# [('s', 'http://www.wikidata.org/entity/Q5873112'), ('sname', 'Hjalmar Dahlberg')]
# [('s', 'http://www.wikidata.org/entity/Q5891540'), ('sname', 'Erik Jonsson')]
# [('s', 'http://www.wikidata.org/entity/Q5992244'), ('sname', 'Ignacio Cáceres')]
# [('s', 'http://www.wikidata.org/entity/Q6019126'), ('sname', 'Evert Nyberg')]
# [('s', 'http://www.wikidata.org/entity/Q1067015'), ('sname', 'Charlie Spedding')]
# [('s', 'http://www.wikidata.org/entity/Q2433125'), ('sname', 'Tilahun Regassa')]
# [('s', 'http://www.wikidata.org/entity/Q20650426'), ('sname', 'Juan Silva')]
# [('s', 'http://www.wikidata.org/entity/Q1128062'), ('sname', 'Constantino León')]
# [('s', 'http://www.wikidata.org/entity/Q20895412'), ('sname', 'Filomena Costa')]
# [('s', 'http://www.wikidata.org/entity/Q4791678'), ('sname', 'Arkadiusz Sowa')]
# [('s', 'http://www.wikidata.org/entity/Q26727449'), ('sname', 'Ian Blackwood')]
# [('s', 'http://www.wikidata.org/entity/Q26728057'), ('sname', 'John Coyle')]
# [('s', 'http://www.wikidata.org/entity/Q26780471'), ('sname', 'Teresa Wanjiku')]
# [('s', 'http://www.wikidata.org/entity/Q720502'), ('sname', 'Daniel Njenga')]
# [('s', 'http://www.wikidata.org/entity/Q725666'), ('sname', 'Moses Mosop')]
# [('s', 'http://www.wikidata.org/entity/Q757806'), ('sname', 'Atsushi Sato')]
# [('s', 'http://www.wikidata.org/entity/Q786834'), ('sname', 'Moges Taye')]
# [('s', 'http://www.wikidata.org/entity/Q1065207'), ('sname', 'Tom Richards')]
# [('s', 'http://www.wikidata.org/entity/Q313811'), ('sname', 'Edwin Flack')]
# [('s', 'http://www.wikidata.org/entity/Q920828'), ('sname', 'Aleksey Sokolov')]
# [('s', 'http://www.wikidata.org/entity/Q928850'), ('sname', 'Doroteo Flores')]
# [('s', 'http://www.wikidata.org/entity/Q1132894'), ('sname', 'Dimitrios Deligiannis')]
# 100

# %%
# aim: get all the athletes who competed in the 4 Olympic Games and whose 'occupation' is 'marathon runner'. Get also their countries
# result: it seems that no marathon athlete have competed in the 4 Olympic Games...
queryString = """
SELECT DISTINCT ?athlete ?athletename ?athletecountry ?athletecountryname 
WHERE {
   # athlete participant in 
   #?athlete wdt:P1344 ?summerolympics .
   
   # ?athlete wdt:P1344 wd:Q8558 .
   # ?athlete wdt:P1344 wd:Q8567 .
   # ?athlete wdt:P1344 wd:Q8577 .
   # ?athlete wdt:P1344 wd:Q8613 .
   
   # athlete occupation marathon runner
   # ?athlete wdt:P106 wd:Q13382460.
   
   # athlete country athletecountry
   # ?athlete wdt:P27 ?athletecountry .
   
   # ?athletecountry sc:name ?athletecountryname .
   
   # get the label
   # ?athlete sc:name ?athletename .
   
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# Empty

# %%
# aim: find all the athletes who played in the 4 Olympic Games
# result: we found some athletes so there are actually athletes who competed in the 4 Olympic Games. Maybe we should consider other optional properties apart from occupation such as
#         'sports discipline competed in' and 'sport'
queryString = """
SELECT DISTINCT ?athlete ?athletename
WHERE {
   # ?athlete wdt:P1344 wd:Q8558 .
   # ?athlete wdt:P1344 wd:Q8567 .
   # ?athlete wdt:P1344 wd:Q8577 .
   # ?athlete wdt:P1344 wd:Q8613 .
   # ?athlete sc:name ?athletename .
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('athlete', 'http://www.wikidata.org/entity/Q2564215'), ('athletename', 'Tony Azevedo')]
# [('athlete', 'http://www.wikidata.org/entity/Q316106'), ('athletename', 'José Manuel Calderón')]
# [('athlete', 'http://www.wikidata.org/entity/Q240686'), ('athletename', 'Chris Brown')]
# [('athlete', 'http://www.wikidata.org/entity/Q1332824'), ('athletename', 'Yūki Ōta')]
# [('athlete', 'http://www.wikidata.org/entity/Q18718'), ('athletename', 'Géza Imre')]
# [('athlete', 'http://www.wikidata.org/entity/Q955360'), ('athletename', 'Aldo Montano')]
# [('athlete', 'http://www.wikidata.org/entity/Q312651'), ('athletename', 'Rudy Fernández')]
# [('athlete', 'http://www.wikidata.org/entity/Q240726'), ('athletename', 'Diana Taurasi')]
# [('athlete', 'http://www.wikidata.org/entity/Q2606477'), ('athletename', 'Pietro Figlioli')]
# [('athlete', 'http://www.wikidata.org/entity/Q282285'), ('athletename', 'Richard Kruse')]
# [('athlete', 'http://www.wikidata.org/entity/Q193052'), ('athletename', 'Pau Gasol')]
# [('athlete', 'http://www.wikidata.org/entity/Q1292922'), ('athletename', 'Damir Burić')]
# [('athlete', 'http://www.wikidata.org/entity/Q2553411'), ('athletename', 'Stefano Tempesti')]
# [('athlete', 'http://www.wikidata.org/entity/Q1392951'), ('athletename', 'Erwann Le Péchoux')]
# [('athlete', 'http://www.wikidata.org/entity/Q430552'), ('athletename', 'Predrag Jokić')]
# [('athlete', 'http://www.wikidata.org/entity/Q3499453'), ('athletename', 'Luisa Kiala')]
# [('athlete', 'http://www.wikidata.org/entity/Q493618'), ('athletename', 'Andrea Cassarà')]
# [('athlete', 'http://www.wikidata.org/entity/Q1763245'), ('athletename', 'Xavier García')]
# [('athlete', 'http://www.wikidata.org/entity/Q77356'), ('athletename', 'Peter Joppich')]
# [('athlete', 'http://www.wikidata.org/entity/Q264333'), ('athletename', 'Erika Villaécija')]
# [('athlete', 'http://www.wikidata.org/entity/Q314071'), ('athletename', 'Luis Scola')]
# [('athlete', 'http://www.wikidata.org/entity/Q3179153'), ('athletename', 'Vasilij Žbogar')]
# [('athlete', 'http://www.wikidata.org/entity/Q2832760'), ('athletename', 'Sandro Campagna')]
# [('athlete', 'http://www.wikidata.org/entity/Q310541'), ('athletename', 'Juan Carlos Navarro')]
# [('athlete', 'http://www.wikidata.org/entity/Q4755394'), ('athletename', 'Andreas Cariolou')]
# [('athlete', 'http://www.wikidata.org/entity/Q352145'), ('athletename', 'Felipe Reyes')]
# [('athlete', 'http://www.wikidata.org/entity/Q255518'), ('athletename', 'Tamika Catchings')]
# [('athlete', 'http://www.wikidata.org/entity/Q352064'), ('athletename', 'Yi Jianlian')]
# [('athlete', 'http://www.wikidata.org/entity/Q3180131'), ('athletename', 'Óscar Figueroa')]
# [('athlete', 'http://www.wikidata.org/entity/Q2559530'), ('athletename', 'Adriana Moisés Pinto')]
# [('athlete', 'http://www.wikidata.org/entity/Q622737'), ('athletename', 'Laura Summerton')]
# [('athlete', 'http://www.wikidata.org/entity/Q2005569'), ('athletename', 'Ratko Rudić')]
# [('athlete', 'http://www.wikidata.org/entity/Q4015813'), ('athletename', 'Vladimir Gojković')]
# [('athlete', 'http://www.wikidata.org/entity/Q444027'), ('athletename', 'Andrés Nocioni')]
# [('athlete', 'http://www.wikidata.org/entity/Q715431'), ('athletename', 'Chen Nan')]
# 35

# %%
# aim: get all the athletes who competed in the 4 Olympic Games and whose 'occupation' is 'marathon runner'. Get also their countries
# result: it seems that no marathon athlete have competed in the 4 Olympic Games...
queryString = """
SELECT DISTINCT ?athlete ?athletename ?athletecountry ?athletecountryname 
WHERE {
   # athlete participant in 
   
   # ?athlete wdt:P1344 wd:Q8558 .
   # ?athlete wdt:P1344 wd:Q8567 .
   # ?athlete wdt:P1344 wd:Q8577 .
   # ?athlete wdt:P1344 wd:Q8613 .
   
   # athlete occupation marathon runner
   # ?athlete wdt:P106 ?occupation .
   # ?athlete wdt:P2416 ?sportcompeted .
   # ?athlete wdt:P641 ?sport .
   
   # athlete country athletecountry
   # ?athlete wdt:P27 ?athletecountry .
   
   # ?athletecountry sc:name ?athletecountryname .
   
   # get the label
   # ?athlete sc:name ?athletename .
   
   FILTER (?occupation=wd:Q13382460 || ?sport=wd:Q40244 || ?sportcompeted=wd:Q40244 )
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# Empty

# %%
# aim: get all the athletes who competed in the 4 Olympic Games and whose 'occupation' is 'marathon runner'. Get also their countries
# result: it seems that no marathon athlete have competed in the 4 Olympic Games...
queryString = """
SELECT DISTINCT ?athlete ?athletename ?athletecountry ?athletecountryname 
WHERE {
   # athlete participant in 
   # ?athlete wdt:P1344 ?summerolympics .
   # ?athletics wdt:P361 ?summerolympics
   # ?marathon wdt:P361 ?athletics 
   

   
   # athlete occupation marathon runner
   # ?athlete wdt:P106 ?occupation .
   # ?athlete wdt:P2416 ?sportcompeted .
   # ?athlete wdt:P641 ?sport .
   
   # athlete country athletecountry
   # ?athlete wdt:P27 ?athletecountry .
   
   # ?athletecountry sc:name ?athletecountryname .
   
   # get the label
   # ?athlete sc:name ?athletename .
   
   FILTER (?summerolympics IN(wd:Q8558,wd:Q8567,wd:Q8577,wd:Q8613)).
   FILTER (?occupation=wd:Q13382460 || ?sport=wd:Q40244 || ?sportcompeted=wd:Q40244 )
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)

# %%
# aim: get all the athletes who competed in the 4 Olympic Games and whose 'occupation' is 'marathon runner'. Get also their countries
# result: it seems that no marathon athlete have competed in the 4 Olympic Games...
#forgot the labels here!!!
queryString = """
SELECT DISTINCT ?athlete ?athletename ?athletecountry ?athletecountryname 
WHERE {

   # ?athletics wdt:P361 ?summerolympics .
   # ?marathon wdt:P361 ?athletics .
   # ?athlete wdt:P1344 ?marathon .
   
   
   # athlete country athletecountry
   # ?athlete wdt:P27 ?athletecountry .
   
   # ?athletecountry sc:name ?athletecountryname .
   
   # get the label
   # ?athlete sc:name ?athletename .
   
   FILTER (?summerolympics IN(wd:Q8558,wd:Q8567,wd:Q8577,wd:Q8613)).
   FILTER REGEX(?athletics, "athletics" ) .
   FILTER REGEX(?marathon, "marathon" ) .
}
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# Empty

# %%
# aim: get all the athletes who competed in one of the 4 Olympic Games in the marathon discipline. Get also their countries
# result: all the athletes who competed in one of the 4 Olympic Games in the marathon discipline.
queryString = """
SELECT DISTINCT ?athlete ?athletename ?athletecountry ?athletecountryname 
WHERE {

   # ?athletics wdt:P361 ?summerolympics ;
       sc:name ?athleticsname.
   # ?marathon wdt:P361 ?athletics ;
       sc:name ?marathonname.
   # ?athlete wdt:P1344 ?marathon .
   
   
   # athlete country athletecountry
   # ?athlete wdt:P27 ?athletecountry .
   
   # ?athletecountry sc:name ?athletecountryname .
   
   # get the label
   # ?athlete sc:name ?athletename .
   
   FILTER (?summerolympics IN(wd:Q8558,wd:Q8567,wd:Q8577,wd:Q8613)).
   #FILTER (?occupation=wd:Q13382460 || ?sport=wd:Q40244 || ?sportcompeted=wd:Q40244 ) .
   FILTER REGEX(?athleticsname, "athletics" ) .
   FILTER REGEX(?marathonname, "marathon" ) .
}
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('athlete', 'http://www.wikidata.org/entity/Q526508'), ('athletename', 'Helalia Johannes'), ('athletecountry', 'http://www.wikidata.org/entity/Q1030'), ('athletecountryname', 'Namibia')]
# [('athlete', 'http://www.wikidata.org/entity/Q1702'), ('athletename', 'Stephen Kiprotich'), ('athletecountry', 'http://www.wikidata.org/entity/Q1036'), ('athletecountryname', 'Uganda')]
# [('athlete', 'http://www.wikidata.org/entity/Q9124'), ('athletename', 'Eliud Kipchoge'), ('athletecountry', 'http://www.wikidata.org/entity/Q114'), ('athletecountryname', 'Kenya')]
# [('athlete', 'http://www.wikidata.org/entity/Q26203953'), ('athletename', 'Evans Kiplagat Barkowet'), ('athletecountry', 'http://www.wikidata.org/entity/Q114'), ('athletecountryname', 'Kenya')]
# [('athlete', 'http://www.wikidata.org/entity/Q24083616'), ('athletename', 'Callum Hawkins'), ('athletecountry', 'http://www.wikidata.org/entity/Q145'), ('athletecountryname', 'United Kingdom')]
# [('athlete', 'http://www.wikidata.org/entity/Q5295728'), ('athletename', 'Dong Guojian'), ('athletecountry', 'http://www.wikidata.org/entity/Q148'), ('athletecountryname', "People's Republic of China")]
# [('athlete', 'http://www.wikidata.org/entity/Q13554449'), ('athletename', 'Paulo Roberto Paula'), ('athletecountry', 'http://www.wikidata.org/entity/Q155'), ('athletecountryname', 'Brazil')]
# [('athlete', 'http://www.wikidata.org/entity/Q24034036'), ('athletename', 'Volha Mazuronak'), ('athletecountry', 'http://www.wikidata.org/entity/Q184'), ('athletecountryname', 'Belarus')]
# [('athlete', 'http://www.wikidata.org/entity/Q20528590'), ('athletename', 'Roman Fosti'), ('athletecountry', 'http://www.wikidata.org/entity/Q191'), ('athletecountryname', 'Estonia')]
# [('athlete', 'http://www.wikidata.org/entity/Q7801786'), ('athletename', 'Tiidrek Nurme'), ('athletecountry', 'http://www.wikidata.org/entity/Q191'), ('athletecountryname', 'Estonia')]
# [('athlete', 'http://www.wikidata.org/entity/Q2301289'), ('athletename', 'Sondre Nordstad Moen'), ('athletecountry', 'http://www.wikidata.org/entity/Q20'), ('athletecountryname', 'Norway')]
# [('athlete', 'http://www.wikidata.org/entity/Q1453442'), ('athletename', 'Oleksandr Sitkovskyy'), ('athletecountry', 'http://www.wikidata.org/entity/Q212'), ('athletecountryname', 'Ukraine')]
# [('athlete', 'http://www.wikidata.org/entity/Q1617873'), ('athletename', 'Marcel Matanin'), ('athletecountry', 'http://www.wikidata.org/entity/Q214'), ('athletecountryname', 'Slovakia')]
# [('athlete', 'http://www.wikidata.org/entity/Q26059275'), ('athletename', 'Lilia Fisikovici'), ('athletecountry', 'http://www.wikidata.org/entity/Q217'), ('athletecountryname', 'Moldova')]
# [('athlete', 'http://www.wikidata.org/entity/Q26203953'), ('athletename', 'Evans Kiplagat Barkowet'), ('athletecountry', 'http://www.wikidata.org/entity/Q227'), ('athletecountryname', 'Azerbaijan')]
# [('athlete', 'http://www.wikidata.org/entity/Q7610012'), ('athletename', 'Stephen Mokoka'), ('athletecountry', 'http://www.wikidata.org/entity/Q258'), ('athletecountryname', 'South Africa')]
# [('athlete', 'http://www.wikidata.org/entity/Q16212038'), ('athletename', 'Paul Pollock'), ('athletecountry', 'http://www.wikidata.org/entity/Q27'), ('athletecountryname', 'Ireland')]
# [('athlete', 'http://www.wikidata.org/entity/Q3072729'), ('athletename', 'Fionnuala McCormack'), ('athletecountry', 'http://www.wikidata.org/entity/Q27'), ('athletecountryname', 'Ireland')]
# [('athlete', 'http://www.wikidata.org/entity/Q26220530'), ('athletename', 'Estela Navascués'), ('athletecountry', 'http://www.wikidata.org/entity/Q29'), ('athletecountryname', 'Spain')]
# [('athlete', 'http://www.wikidata.org/entity/Q4376764'), ('athletename', 'Abdi Nageeye'), ('athletecountry', 'http://www.wikidata.org/entity/Q29999'), ('athletecountryname', 'Kingdom of the Netherlands')]
# 20

# %%
# aim: get all the athletes who competed in one of the 4 Olympic Games in the marathon discipline and the number of Olympic Games the athlete competed in. Get also their countries
# result: all the athletes who competed in one of the 4 Olympic Games in the marathon discipline.
queryString = """
SELECT DISTINCT ?athlete ?athletename ?athletecountry ?athletecountryname (COUNT(?summerolympics) as ?olympicsplayed)
WHERE {

   # ?athletics wdt:P361 ?summerolympics ;
       sc:name ?athleticsname.
   # ?marathon wdt:P361 ?athletics ;
       sc:name ?marathonname.
   # ?athlete wdt:P1344 ?marathon .
   
   
   # athlete country athletecountry
   # ?athlete wdt:P27 ?athletecountry .
   
   # ?athletecountry sc:name ?athletecountryname .
   
   # get the label
   # ?athlete sc:name ?athletename .
   
   FILTER (?summerolympics IN(wd:Q8558,wd:Q8567,wd:Q8577,wd:Q8613)).
   #FILTER (?occupation=wd:Q13382460 || ?sport=wd:Q40244 || ?sportcompeted=wd:Q40244 ) .
   FILTER REGEX(?athleticsname, "athletics" ) .
   FILTER REGEX(?marathonname, "marathon" ) .
} GROUP BY ?athlete ?athletename ?athletecountry ?athletecountryname
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('athlete', 'http://www.wikidata.org/entity/Q26472786'), ('athletename', 'Cristhian Pacheco'), ('athletecountry', 'http://www.wikidata.org/entity/Q419'), ('athletecountryname', 'Peru'), ('olympicsplayed', '1')]
# [('athlete', 'http://www.wikidata.org/entity/Q9124'), ('athletename', 'Eliud Kipchoge'), ('athletecountry', 'http://www.wikidata.org/entity/Q114'), ('athletecountryname', 'Kenya'), ('olympicsplayed', '1')]
# [('athlete', 'http://www.wikidata.org/entity/Q2301289'), ('athletename', 'Sondre Nordstad Moen'), ('athletecountry', 'http://www.wikidata.org/entity/Q20'), ('athletecountryname', 'Norway'), ('olympicsplayed', '1')]
# [('athlete', 'http://www.wikidata.org/entity/Q2271929'), ('athletename', 'Bat-Ochiryn Ser-Od'), ('athletecountry', 'http://www.wikidata.org/entity/Q711'), ('athletecountryname', 'Mongolia'), ('olympicsplayed', '4')]
# [('athlete', 'http://www.wikidata.org/entity/Q63691'), ('athletename', 'Galen Rupp'), ('athletecountry', 'http://www.wikidata.org/entity/Q30'), ('athletecountryname', 'United States of America'), ('olympicsplayed', '1')]
# [('athlete', 'http://www.wikidata.org/entity/Q22002466'), ('athletename', 'Jared Ward'), ('athletecountry', 'http://www.wikidata.org/entity/Q30'), ('athletecountryname', 'United States of America'), ('olympicsplayed', '1')]
# [('athlete', 'http://www.wikidata.org/entity/Q19365752'), ('athletename', 'Tadesse Abraham'), ('athletecountry', 'http://www.wikidata.org/entity/Q39'), ('athletecountryname', 'Switzerland'), ('olympicsplayed', '1')]
# [('athlete', 'http://www.wikidata.org/entity/Q7367027'), ('athletename', 'Rosa Chacha'), ('athletecountry', 'http://www.wikidata.org/entity/Q736'), ('athletecountryname', 'Ecuador'), ('olympicsplayed', '2')]
# [('athlete', 'http://www.wikidata.org/entity/Q26464315'), ('athletename', 'Ahn Seul-ki'), ('athletecountry', 'http://www.wikidata.org/entity/Q884'), ('athletecountryname', 'South Korea'), ('olympicsplayed', '1')]
# [('athlete', 'http://www.wikidata.org/entity/Q20988443'), ('athletename', 'Alphonce Simbu'), ('athletecountry', 'http://www.wikidata.org/entity/Q924'), ('athletecountryname', 'Tanzania'), ('olympicsplayed', '1')]
# [('athlete', 'http://www.wikidata.org/entity/Q20528590'), ('athletename', 'Roman Fosti'), ('athletecountry', 'http://www.wikidata.org/entity/Q191'), ('athletecountryname', 'Estonia'), ('olympicsplayed', '1')]
# [('athlete', 'http://www.wikidata.org/entity/Q1453442'), ('athletename', 'Oleksandr Sitkovskyy'), ('athletecountry', 'http://www.wikidata.org/entity/Q212'), ('athletecountryname', 'Ukraine'), ('olympicsplayed', '2')]
# [('athlete', 'http://www.wikidata.org/entity/Q26268001'), ('athletename', 'Jovana de la Cruz'), ('athletecountry', 'http://www.wikidata.org/entity/Q419'), ('athletecountryname', 'Peru'), ('olympicsplayed', '1')]
# [('athlete', 'http://www.wikidata.org/entity/Q6820977'), ('athletename', 'Meryem Erdoğan'), ('athletecountry', 'http://www.wikidata.org/entity/Q43'), ('athletecountryname', 'Turkey'), ('olympicsplayed', '1')]
# [('athlete', 'http://www.wikidata.org/entity/Q20988054'), ('athletename', 'Munkhzaya Bayartsogt'), ('athletecountry', 'http://www.wikidata.org/entity/Q711'), ('athletecountryname', 'Mongolia'), ('olympicsplayed', '1')]
# [('athlete', 'http://www.wikidata.org/entity/Q7367027'), ('athletename', 'Rosa Chacha'), ('athletecountry', 'http://www.wikidata.org/entity/Q739'), ('athletecountryname', 'Colombia'), ('olympicsplayed', '2')]
# [('athlete', 'http://www.wikidata.org/entity/Q769607'), ('athletename', 'Augusto Ramos Soares'), ('athletecountry', 'http://www.wikidata.org/entity/Q574'), ('athletecountryname', 'East Timor'), ('olympicsplayed', '2')]
# [('athlete', 'http://www.wikidata.org/entity/Q7610012'), ('athletename', 'Stephen Mokoka'), ('athletecountry', 'http://www.wikidata.org/entity/Q258'), ('athletecountryname', 'South Africa'), ('olympicsplayed', '1')]
# [('athlete', 'http://www.wikidata.org/entity/Q13554449'), ('athletename', 'Paulo Roberto Paula'), ('athletecountry', 'http://www.wikidata.org/entity/Q155'), ('athletecountryname', 'Brazil'), ('olympicsplayed', '2')]
# [('athlete', 'http://www.wikidata.org/entity/Q1617873'), ('athletename', 'Marcel Matanin'), ('athletecountry', 'http://www.wikidata.org/entity/Q214'), ('athletecountryname', 'Slovakia'), ('olympicsplayed', '1')]
# 20

# %%
# aim: get all the athletes who competed in the 4 Olympic Games in the marathon discipline and the number of Olympic Games the athlete competed in. Get also their countries
# result: all the athletes who competed in the 4 Olympic Games in the marathon discipline. We only got one athlete so we might want to consider all the athletes whose
#         sport is 'marathon' or occupation is 'marathon runner' that have participated in any event
queryString = """
SELECT DISTINCT ?athlete ?athletename ?athletecountry ?athletecountryname (COUNT(?summerolympics) as ?olympicsplayed)
WHERE {

   # ?athletics wdt:P361 ?summerolympics ;
       sc:name ?athleticsname.
   # ?marathon wdt:P361 ?athletics ;
       sc:name ?marathonname.
   # ?athlete wdt:P1344 ?marathon .
   
   
   # athlete country athletecountry
   # ?athlete wdt:P27 ?athletecountry .
   
   # ?athletecountry sc:name ?athletecountryname .
   
   # get the label
   # ?athlete sc:name ?athletename .
   
   FILTER (?summerolympics IN(wd:Q8558,wd:Q8567,wd:Q8577,wd:Q8613)).
   FILTER REGEX(?athleticsname, "athletics" ) .
   FILTER REGEX(?marathonname, "marathon" ) .
} GROUP BY ?athlete ?athletename ?athletecountry ?athletecountryname
HAVING (COUNT(?summerolympics)>=4)
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('athlete', 'http://www.wikidata.org/entity/Q2271929'), ('athletename', 'Bat-Ochiryn Ser-Od'), ('athletecountry', 'http://www.wikidata.org/entity/Q711'), ('athletecountryname', 'Mongolia'), ('olympicsplayed', '4')]
# 1

# %%
# aim: get all the athletes whose 'sport' is 'marathon' or whose occupation is 'marathon runner' who played in any possible event in all the Olympic Games of 2004.
#      We consider all the events since if considering only marathon events this would return only the athlete 'Bat-Ochiryn Ser-Od' as result
# result: there are few athletes...probably the query is wrong. We try to reformulate it

queryString = """
SELECT DISTINCT ?athlete ?athletename
WHERE {

   # ?discipline wdt:P361 wd:Q8558 .

   # ?subdiscipline wdt:P361 ?discipline .

   
   # athlete participated in any possible discipline at the Olympic Games of 2004
   OPTIONAL {?athlete ?participated ?subdiscipline} .
   OPTIONAL {?athlete ?participated ?discipline} .
   OPTIONAL {?athlete ?participated wd:Q8558} .
   
   # athlete occupation marathon runner
   # ?athlete wdt:P106 ?occupation .
   # ?athlete wdt:P2416 ?sportcompeted .
   # ?athlete wdt:P641 ?sport .
   
   # athlete country athletecountry
   # ?athlete wdt:P27 ?athletecountry .
   
   # ?athletecountry sc:name ?athletecountryname .
   
   # get the label
   # ?athlete sc:name ?athletename .
   
   FILTER (?occupation=wd:Q13382460 || ?sport=wd:Q40244 || ?sportcompeted=wd:Q40244 ) .
   FILTER (?participated=wdt:P1344) .
   
} GROUP BY ?athlete ?athletename
HAVING (COUNT(?participated)>=1)
LIMIT 20
"""
print("Results")
x=run_query(queryString)
# Out:
# Results
# [('athlete', 'http://www.wikidata.org/entity/Q2271929'), ('athletename', 'Bat-Ochiryn Ser-Od')]
# [('athlete', 'http://www.wikidata.org/entity/Q9124'), ('athletename', 'Eliud Kipchoge')]
# [('athlete', 'http://www.wikidata.org/entity/Q1617873'), ('athletename', 'Marcel Matanin')]
# 3

# %%
# aim: get all the athletes whose 'sport' is 'marathon' or whose occupation is 'marathon runner' who played in any possible event in all the Olympic Games of 2004.
#      We consider all the events since if considering only marathon events this would return only the athlete 'Bat-Ochiryn Ser-Od' as result
# result:all the athletes whose 'sport' is 'marathon' or whose occupation is 'marathon runner' who played in any possible event in all the Olympic Games of 2004-2008-
#      2012-2016.

queryString = """
SELECT DISTINCT ?athlete ?athletename
WHERE {
   # ?discipline wdt:P361 wd:Q8558 .

   # ?subdiscipline wdt:P361 ?discipline .
   
   # athlete participated in any possible discipline at the Olympic Games of 2004
   # ?athlete wdt:P1344 ?anydiscipline .
   
   # athlete occupation marathon runner
   # ?athlete wdt:P106 ?occupation .
   # ?athlete wdt:P2416 ?sportcompeted .
   # ?athlete wdt:P641 ?sport .
   
   # athlete country athletecountry
   # ?athlete wdt:P27 ?athletecountry .
   
   # ?athletecountry sc:name ?athletecountryname .
   
   # get the label
   # ?athlete sc:name ?athletename .
   
   FILTER (?occupation=wd:Q13382460 || ?sport=wd:Q40244 || ?sportcompeted=wd:Q40244 ) .
   FILTER (?anydiscipline=wd:Q8558 || ?anydiscipline=?discipline || ?anydiscipline=?subdiscipline)
   
} GROUP BY ?athlete ?athletename
LIMIT 20
"""
print("Results")
x=run_query(queryString)
# Out:
# Results
# [('athlete', 'http://www.wikidata.org/entity/Q433878'), ('athletename', 'Nadia Ejjafini')]
# [('athlete', 'http://www.wikidata.org/entity/Q6392970'), ('athletename', 'Kenza Wahbi')]
# [('athlete', 'http://www.wikidata.org/entity/Q171500'), ('athletename', 'Gebrselassie Haile')]
# [('athlete', 'http://www.wikidata.org/entity/Q466315'), ('athletename', 'Derartu Tulu')]
# [('athlete', 'http://www.wikidata.org/entity/Q429888'), ('athletename', 'Werknesh Kidane')]
# [('athlete', 'http://www.wikidata.org/entity/Q6763145'), ('athletename', 'Mariela González')]
# [('athlete', 'http://www.wikidata.org/entity/Q16210935'), ('athletename', 'Maria McCambridge')]
# [('athlete', 'http://www.wikidata.org/entity/Q274104'), ('athletename', 'Benita Johnson')]
# [('athlete', 'http://www.wikidata.org/entity/Q1384426'), ('athletename', 'Wu Wen-Chien')]
# [('athlete', 'http://www.wikidata.org/entity/Q2448283'), ('athletename', 'Ndabili Bashingili')]
# [('athlete', 'http://www.wikidata.org/entity/Q276222'), ('athletename', 'Asha Gigi')]
# [('athlete', 'http://www.wikidata.org/entity/Q5491888'), ('athletename', 'Franklin Tenorio')]
# [('athlete', 'http://www.wikidata.org/entity/Q730788'), ('athletename', 'Li Zhuhong')]
# [('athlete', 'http://www.wikidata.org/entity/Q1108991'), ('athletename', 'Colleen De Reuck')]
# [('athlete', 'http://www.wikidata.org/entity/Q954275'), ('athletename', 'Meb Keflezighi')]
# [('athlete', 'http://www.wikidata.org/entity/Q2804268'), ('athletename', 'Haley McGregor')]
# [('athlete', 'http://www.wikidata.org/entity/Q1703416'), ('athletename', 'Jong Yong-Ok')]
# [('athlete', 'http://www.wikidata.org/entity/Q1992162'), ('athletename', 'Nili Abramski')]
# [('athlete', 'http://www.wikidata.org/entity/Q2789952'), ('athletename', 'Abdelhak Zakaria')]
# [('athlete', 'http://www.wikidata.org/entity/Q448810'), ('athletename', 'Ulrike Maisch')]
# 20

# %%
# aim: get all the athletes whose 'sport' is 'marathon' or whose occupation is 'marathon runner' who played in any possible event in all the Olympic Games of 2004-2008-
#      2012-2016. We consider all the events since if considering only marathon events this would return only the athlete 'Bat-Ochiryn Ser-Od' as result
# result:all the athletes whose 'sport' is 'marathon' or whose occupation is 'marathon runner' who played in any possible event in all the Olympic Games of 2004-2008-
#      2012-2016.

queryString = """
SELECT DISTINCT ?athlete ?athletename
WHERE {
    {
        SELECT DISTINCT ?athlete ?athletename
        WHERE {
           # ?discipline wdt:P361 wd:Q8558 .

           # ?subdiscipline wdt:P361 ?discipline .


           # athlete participated in any possible discipline at the Olympic Games of 2004
           # ?athlete wdt:P1344 ?anydiscipline .

           # athlete occupation marathon runner
           # ?athlete wdt:P106 ?occupation .
           # ?athlete wdt:P2416 ?sportcompeted .
           # ?athlete wdt:P641 ?sport .

           # athlete country athletecountry
           # ?athlete wdt:P27 ?athletecountry .

           # ?athletecountry sc:name ?athletecountryname .

           # get the label
           # ?athlete sc:name ?athletename .

           FILTER (?occupation=wd:Q13382460 || ?sport=wd:Q40244 || ?sportcompeted=wd:Q40244 ) .
           FILTER (?anydiscipline=wd:Q8558 || ?anydiscipline=?discipline || ?anydiscipline=?subdiscipline)

        }
    }
    .
    {
        SELECT DISTINCT ?athlete ?athletename
        WHERE {
           # ?discipline wdt:P361 wd:Q8567 . 

           # ?subdiscipline wdt:P361 ?discipline .


           # athlete participated in any possible discipline at the Olympic Games of 2008
           # ?athlete wdt:P1344 ?anydiscipline .

           # athlete occupation marathon runner
           # ?athlete wdt:P106 ?occupation .
           # ?athlete wdt:P2416 ?sportcompeted .
           # ?athlete wdt:P641 ?sport .

           # athlete country athletecountry
           # ?athlete wdt:P27 ?athletecountry .

           # ?athletecountry sc:name ?athletecountryname .

           # get the label
           # ?athlete sc:name ?athletename .

           FILTER (?occupation=wd:Q13382460 || ?sport=wd:Q40244 || ?sportcompeted=wd:Q40244 ) .
           FILTER (?anydiscipline=wd:Q8567 || ?anydiscipline=?discipline || ?anydiscipline=?subdiscipline)

        }
    }
    .
    {
        SELECT DISTINCT ?athlete ?athletename
        WHERE {
           # ?discipline wdt:P361 wd:Q8577 .

           # ?subdiscipline wdt:P361 ?discipline .


           # athlete participated in any possible discipline at the Olympic Games of 2012
           # ?athlete wdt:P1344 ?anydiscipline .

           # athlete occupation marathon runner
           # ?athlete wdt:P106 ?occupation .
           # ?athlete wdt:P2416 ?sportcompeted .
           # ?athlete wdt:P641 ?sport .

           # athlete country athletecountry
           # ?athlete wdt:P27 ?athletecountry .

           # ?athletecountry sc:name ?athletecountryname .

           # get the label
           # ?athlete sc:name ?athletename .

           FILTER (?occupation=wd:Q13382460 || ?sport=wd:Q40244 || ?sportcompeted=wd:Q40244 ) .
           FILTER (?anydiscipline=wd:Q8577 || ?anydiscipline=?discipline || ?anydiscipline=?subdiscipline)

        }
    }
    .
    {
        SELECT DISTINCT ?athlete ?athletename
        WHERE {
           # ?discipline wdt:P361 wd:Q8613 .

           # ?subdiscipline wdt:P361 ?discipline .


           # athlete participated in any possible discipline at the Olympic Games of 2016
           # ?athlete wdt:P1344 ?anydiscipline .

           # athlete occupation marathon runner
           # ?athlete wdt:P106 ?occupation .
           # ?athlete wdt:P2416 ?sportcompeted .
           # ?athlete wdt:P641 ?sport .

           # athlete country athletecountry
           # ?athlete wdt:P27 ?athletecountry .

           # ?athletecountry sc:name ?athletecountryname .

           # get the label
           # ?athlete sc:name ?athletename .

           FILTER (?occupation=wd:Q13382460 || ?sport=wd:Q40244 || ?sportcompeted=wd:Q40244 ) .
           FILTER (?anydiscipline=wd:Q8613 || ?anydiscipline=?discipline || ?anydiscipline=?subdiscipline)

        }
    }
}
LIMIT 20
"""
print("Results")
x=run_query(queryString)
# Out:
# Results
# [('athlete', 'http://www.wikidata.org/entity/Q192033'), ('athletename', 'Zersenay Tadese')]
# [('athlete', 'http://www.wikidata.org/entity/Q443822'), ('athletename', 'Joanne Pavey')]
# [('athlete', 'http://www.wikidata.org/entity/Q267879'), ('athletename', 'Olivera Jevtić')]
# [('athlete', 'http://www.wikidata.org/entity/Q467303'), ('athletename', 'Souad Aït Salem')]
# [('athlete', 'http://www.wikidata.org/entity/Q2271929'), ('athletename', 'Bat-Ochiryn Ser-Od')]
# [('athlete', 'http://www.wikidata.org/entity/Q6003'), ('athletename', 'Tirunesh Dibaba')]
# [('athlete', 'http://www.wikidata.org/entity/Q449558'), ('athletename', 'Kayoko Fukushi')]
# 7

# %% [markdown]
# Final query for this task

# %%
# aim: get all the athletes'countries whose 'sport' is 'marathon' or whose occupation is 'marathon runner' who played in any possible event in all the Olympic Games of 2004-2008-
#      2012-2016. We consider all the events since if considering only marathon events this would return only the athlete 'Bat-Ochiryn Ser-Od' as result.
# result:all the athletes whose 'sport' is 'marathon' or whose occupation is 'marathon runner' who played in any possible event in all the Olympic Games of 2004-2008-
#      2012-2016.

queryString = """
SELECT DISTINCT ?athletecountry ?athletecountryname (COUNT(?athlete) as ?numberathletes)
WHERE {
    {
        SELECT DISTINCT ?athlete ?athletecountry ?athletecountryname
        WHERE {
           # ?discipline wdt:P361 wd:Q8558 .

           # ?subdiscipline wdt:P361 ?discipline .


           # athlete participated in any possible discipline at the Olympic Games of 2004
           # ?athlete wdt:P1344 ?anydiscipline .

           # athlete occupation marathon runner
           # ?athlete wdt:P106 ?occupation .
           # ?athlete wdt:P2416 ?sportcompeted .
           # ?athlete wdt:P641 ?sport .

           # athlete country athletecountry
           # ?athlete wdt:P27 ?athletecountry .

           # ?athletecountry sc:name ?athletecountryname .

           FILTER (?occupation=wd:Q13382460 || ?sport=wd:Q40244 || ?sportcompeted=wd:Q40244 ) .
           FILTER (?anydiscipline=wd:Q8558 || ?anydiscipline=?discipline || ?anydiscipline=?subdiscipline)

        }
    }
    .
    {
        SELECT DISTINCT ?athlete ?athletecountry ?athletecountryname
        WHERE {
           # ?discipline wdt:P361 wd:Q8567 . 

           # ?subdiscipline wdt:P361 ?discipline .


           # athlete participated in any possible discipline at the Olympic Games of 2008
           # ?athlete wdt:P1344 ?anydiscipline .

           # athlete occupation marathon runner
           # ?athlete wdt:P106 ?occupation .
           # ?athlete wdt:P2416 ?sportcompeted .
           # ?athlete wdt:P641 ?sport .

           # athlete country athletecountry
           # ?athlete wdt:P27 ?athletecountry .

           # ?athletecountry sc:name ?athletecountryname .

           FILTER (?occupation=wd:Q13382460 || ?sport=wd:Q40244 || ?sportcompeted=wd:Q40244 ) .
           FILTER (?anydiscipline=wd:Q8567 || ?anydiscipline=?discipline || ?anydiscipline=?subdiscipline)

        }
    }
    .
    {
        SELECT DISTINCT ?athlete ?athletecountry ?athletecountryname
        WHERE {
           # ?discipline wdt:P361 wd:Q8577 .

           # ?subdiscipline wdt:P361 ?discipline .


           # athlete participated in any possible discipline at the Olympic Games of 2012
           # ?athlete wdt:P1344 ?anydiscipline .

           # athlete occupation marathon runner
           # ?athlete wdt:P106 ?occupation .
           # ?athlete wdt:P2416 ?sportcompeted .
           # ?athlete wdt:P641 ?sport .

           # athlete country athletecountry
           # ?athlete wdt:P27 ?athletecountry .

           # ?athletecountry sc:name ?athletecountryname .

           FILTER (?occupation=wd:Q13382460 || ?sport=wd:Q40244 || ?sportcompeted=wd:Q40244 ) .
           FILTER (?anydiscipline=wd:Q8577 || ?anydiscipline=?discipline || ?anydiscipline=?subdiscipline)

        }
    }
    .
    {
        SELECT DISTINCT ?athlete ?athletecountry ?athletecountryname
        WHERE {
           # ?discipline wdt:P361 wd:Q8613 .

           # ?subdiscipline wdt:P361 ?discipline .


           # athlete participated in any possible discipline at the Olympic Games of 2016
           # ?athlete wdt:P1344 ?anydiscipline .

           # athlete occupation marathon runner
           # ?athlete wdt:P106 ?occupation .
           # ?athlete wdt:P2416 ?sportcompeted .
           # ?athlete wdt:P641 ?sport .

           # athlete country athletecountry
           # ?athlete wdt:P27 ?athletecountry .

           # ?athletecountry sc:name ?athletecountryname .

           FILTER (?occupation=wd:Q13382460 || ?sport=wd:Q40244 || ?sportcompeted=wd:Q40244 ) .
           FILTER (?anydiscipline=wd:Q8613 || ?anydiscipline=?discipline || ?anydiscipline=?subdiscipline)

        }
    }
} GROUP BY ?athletecountry ?athletecountryname
LIMIT 200
"""
print("Results")
x=run_query(queryString)
# Out:
# Results
# [('athletecountry', 'http://www.wikidata.org/entity/Q986'), ('athletecountryname', 'Eritrea'), ('numberathletes', '1')]
# [('athletecountry', 'http://www.wikidata.org/entity/Q403'), ('athletecountryname', 'Serbia'), ('numberathletes', '1')]
# [('athletecountry', 'http://www.wikidata.org/entity/Q711'), ('athletecountryname', 'Mongolia'), ('numberathletes', '1')]
# [('athletecountry', 'http://www.wikidata.org/entity/Q262'), ('athletecountryname', 'Algeria'), ('numberathletes', '1')]
# [('athletecountry', 'http://www.wikidata.org/entity/Q17'), ('athletecountryname', 'Japan'), ('numberathletes', '1')]
# [('athletecountry', 'http://www.wikidata.org/entity/Q145'), ('athletecountryname', 'United Kingdom'), ('numberathletes', '1')]
# [('athletecountry', 'http://www.wikidata.org/entity/Q115'), ('athletecountryname', 'Ethiopia'), ('numberathletes', '1')]
# 7

# %% [markdown]
# ## Task 7
# For each disciplines of the long distance running find who hold the World Record (the result set must be a list of elements with discipline IRI, label and athlete IRI and label).

# %%
# aim: get all the properties of 'long-distance runner'
# result: we found 'field of this occupation'
queryString = """
SELECT DISTINCT ?p ?name
WHERE {
   # bind something
   wd:Q4439155 ?p ?o .
   # get the label
   # ?p sc:name ?name .
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P1889'), ('name', 'different from')]
# [('p', 'http://www.wikidata.org/prop/direct/P2671'), ('name', 'Google Knowledge Graph ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('name', 'subclass of')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('name', 'instance of')]
# [('p', 'http://www.wikidata.org/prop/direct/P373'), ('name', 'Commons category')]
# [('p', 'http://www.wikidata.org/prop/direct/P425'), ('name', 'field of this occupation')]
# [('p', 'http://www.wikidata.org/prop/direct/P910'), ('name', "topic's main category")]
# 7

# %%
# aim: get the object related to 'long-distance runner' through 'field of this occupation'
# result: we found 'long-distance running'
queryString = """
SELECT DISTINCT ?o ?name
WHERE {
   # bind something
   wd:Q4439155 wdt:P425 ?o .
   # get the label
   # ?o sc:name ?name .
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('o', 'http://www.wikidata.org/entity/Q917206'), ('name', 'long-distance running')]
# 1

# %%
# aim: get all the properties related to 'long-distance running'
# result: we found 'part of'
queryString = """
SELECT DISTINCT ?p ?name
WHERE {
   # bind something
   # ?s ?p wd:Q917206 .
   # get the label
   # ?p sc:name ?name .
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('p', 'http://www.wikidata.org/prop/direct/P156'), ('name', 'followed by')]
# [('p', 'http://www.wikidata.org/prop/direct/P2416'), ('name', 'sports discipline competed in')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('name', 'subclass of')]
# [('p', 'http://www.wikidata.org/prop/direct/P301'), ('name', "category's main topic")]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('name', 'instance of')]
# [('p', 'http://www.wikidata.org/prop/direct/P361'), ('name', 'part of')]
# [('p', 'http://www.wikidata.org/prop/direct/P413'), ('name', 'position played on team / speciality')]
# [('p', 'http://www.wikidata.org/prop/direct/P425'), ('name', 'field of this occupation')]
# [('p', 'http://www.wikidata.org/prop/direct/P641'), ('name', 'sport')]
# [('p', 'http://www.wikidata.org/prop/direct/P921'), ('name', 'main subject')]
# 11

# %%
# aim: get all the subjects related to 'long-distance running' through 'part of'
# result: we found just '5k run' but there should be many disciplines
queryString = """
SELECT DISTINCT ?s ?name
WHERE {
   # bind something
   # ?s wdt:P361 wd:Q917206 .
   # get the label
   # ?s sc:name ?name .
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('s', 'http://www.wikidata.org/entity/Q9171043'), ('name', '5K run')]
# 1

# %%
# aim: get all the subjects related to 'long-distance running' through 'sports discipline competed in'
# result: we found athletes and not disciplines
queryString = """
SELECT DISTINCT ?s ?name
WHERE {
   # bind something
   # ?s wdt:P2416 wd:Q917206 .
   # get the label
   # ?s sc:name ?name .
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('s', 'http://www.wikidata.org/entity/Q310447'), ('name', 'Ville Ritola')]
# [('s', 'http://www.wikidata.org/entity/Q14912256'), ('name', 'Günter Wöller')]
# [('s', 'http://www.wikidata.org/entity/Q28074111'), ('name', 'Christel Rogiers')]
# [('s', 'http://www.wikidata.org/entity/Q35309646'), ('name', 'Ignas Brasevičius')]
# [('s', 'http://www.wikidata.org/entity/Q29963964'), ('name', 'Krishna Bahadur Basnet')]
# [('s', 'http://www.wikidata.org/entity/Q29964020'), ('name', 'Hassan Karimou')]
# [('s', 'http://www.wikidata.org/entity/Q225913'), ('name', 'Miruts Yifter')]
# [('s', 'http://www.wikidata.org/entity/Q274531'), ('name', 'Maura Viceconte')]
# [('s', 'http://www.wikidata.org/entity/Q983623'), ('name', 'Mariano Haro')]
# [('s', 'http://www.wikidata.org/entity/Q5998'), ('name', 'Vivian Cheruiyot')]
# [('s', 'http://www.wikidata.org/entity/Q5936464'), ('name', 'Otto Larsen')]
# [('s', 'http://www.wikidata.org/entity/Q11478626'), ('name', 'Shinji Kawashima')]
# [('s', 'http://www.wikidata.org/entity/Q27824999'), ('name', 'Geoffrey Yegon')]
# [('s', 'http://www.wikidata.org/entity/Q27825781'), ('name', 'Eliud Ngetich')]
# [('s', 'http://www.wikidata.org/entity/Q29646625'), ('name', 'Myitung Naw')]
# [('s', 'http://www.wikidata.org/entity/Q42393780'), ('name', 'Robel Fsiha')]
# [('s', 'http://www.wikidata.org/entity/Q5877'), ('name', 'Meseret Defar')]
# [('s', 'http://www.wikidata.org/entity/Q20736637'), ('name', 'Alisa Vainio')]
# [('s', 'http://www.wikidata.org/entity/Q29654376'), ('name', 'Gerhart Hecker')]
# [('s', 'http://www.wikidata.org/entity/Q29789364'), ('name', 'Mohamed Hadheb Hannachi')]
# [('s', 'http://www.wikidata.org/entity/Q29789409'), ('name', 'Nguyễn Văn Lý')]
# [('s', 'http://www.wikidata.org/entity/Q30077567'), ('name', 'João Carvalho')]
# [('s', 'http://www.wikidata.org/entity/Q30077635'), ('name', 'José Torres')]
# [('s', 'http://www.wikidata.org/entity/Q30078543'), ('name', 'Marco Condori')]
# [('s', 'http://www.wikidata.org/entity/Q60827443'), ('name', 'Sardana Trofimova')]
# [('s', 'http://www.wikidata.org/entity/Q16618141'), ('name', 'Yomif Kejelcha')]
# [('s', 'http://www.wikidata.org/entity/Q29974717'), ('name', 'Inni Aboubacar')]
# [('s', 'http://www.wikidata.org/entity/Q29974727'), ('name', 'Benjamin Longiros')]
# [('s', 'http://www.wikidata.org/entity/Q30006091'), ('name', 'Alain Razahasoa')]
# [('s', 'http://www.wikidata.org/entity/Q30006144'), ('name', 'Myint Kan')]
# [('s', 'http://www.wikidata.org/entity/Q30007343'), ('name', 'Paul Kuété')]
# [('s', 'http://www.wikidata.org/entity/Q42343183'), ('name', 'Omar Hassan Omar')]
# [('s', 'http://www.wikidata.org/entity/Q42849808'), ('name', "Thomas O'Riordan")]
# [('s', 'http://www.wikidata.org/entity/Q61756921'), ('name', 'Lodkeo Inthakoumman')]
# [('s', 'http://www.wikidata.org/entity/Q71874734'), ('name', 'Deborah Schöneborn')]
# [('s', 'http://www.wikidata.org/entity/Q72503570'), ('name', 'Rabea Schöneborn')]
# [('s', 'http://www.wikidata.org/entity/Q24265525'), ('name', 'Yasemin Can')]
# [('s', 'http://www.wikidata.org/entity/Q42953427'), ('name', 'Cormac Finnerty')]
# [('s', 'http://www.wikidata.org/entity/Q80196602'), ('name', 'Vincent Kipchumba')]
# [('s', 'http://www.wikidata.org/entity/Q59770543'), ('name', 'Frank Futselaar')]
# [('s', 'http://www.wikidata.org/entity/Q65229730'), ('name', 'Osvald Johansen')]
# [('s', 'http://www.wikidata.org/entity/Q96699425'), ('name', 'Okubay Tsegay')]
# [('s', 'http://www.wikidata.org/entity/Q692387'), ('name', 'Arne Gabius')]
# [('s', 'http://www.wikidata.org/entity/Q2311088'), ('name', 'Teresa Kidd')]
# [('s', 'http://www.wikidata.org/entity/Q88730281'), ('name', 'Hiroki Abe')]
# [('s', 'http://www.wikidata.org/entity/Q100981087'), ('name', 'Lina Kiriliuk')]
# [('s', 'http://www.wikidata.org/entity/Q10309716'), ('name', 'José João da Silva')]
# [('s', 'http://www.wikidata.org/entity/Q29789497'), ('name', 'Hedhili Ben Boubaker')]
# [('s', 'http://www.wikidata.org/entity/Q23902207'), ('name', "Emmanuel M'Pioh")]
# [('s', 'http://www.wikidata.org/entity/Q23902208'), ('name', 'Ismael Mahmoud Ghassab')]
# [('s', 'http://www.wikidata.org/entity/Q29855453'), ('name', 'Ezequiel Baeza')]
# [('s', 'http://www.wikidata.org/entity/Q29855602'), ('name', 'Anatoly Sukharkov')]
# [('s', 'http://www.wikidata.org/entity/Q29866779'), ('name', 'Ryu Man-hyong')]
# [('s', 'http://www.wikidata.org/entity/Q29885953'), ('name', 'Rafael Mora')]
# [('s', 'http://www.wikidata.org/entity/Q29916375'), ('name', 'Leodigard Martin')]
# [('s', 'http://www.wikidata.org/entity/Q29933343'), ('name', 'Ibrahim Al-Taher')]
# [('s', 'http://www.wikidata.org/entity/Q30078472'), ('name', 'Sarath Prasanna Gamage')]
# [('s', 'http://www.wikidata.org/entity/Q35308117'), ('name', 'Yohanes Ghebregergis')]
# [('s', 'http://www.wikidata.org/entity/Q85112292'), ('name', 'Jasmijn Lau')]
# [('s', 'http://www.wikidata.org/entity/Q97999492'), ('name', 'Arnold Rogers')]
# [('s', 'http://www.wikidata.org/entity/Q6120994'), ('name', 'Santiago Manguán')]
# [('s', 'http://www.wikidata.org/entity/Q29295760'), ('name', 'Eddie Fitzgerald')]
# [('s', 'http://www.wikidata.org/entity/Q29642368'), ('name', 'Jaroslav Šourek')]
# [('s', 'http://www.wikidata.org/entity/Q97012688'), ('name', 'Ibrahim Ezzaydouni')]
# [('s', 'http://www.wikidata.org/entity/Q97119842'), ('name', 'Jiksa Tolosa')]
# [('s', 'http://www.wikidata.org/entity/Q52589'), ('name', 'Emil Zátopek')]
# [('s', 'http://www.wikidata.org/entity/Q69635196'), ('name', 'Kohei Futaoka')]
# [('s', 'http://www.wikidata.org/entity/Q96739322'), ('name', 'Andrew Epperson')]
# [('s', 'http://www.wikidata.org/entity/Q96748043'), ('name', 'Rina Cjuro')]
# [('s', 'http://www.wikidata.org/entity/Q96755348'), ('name', 'Mathilde Sénéchal')]
# [('s', 'http://www.wikidata.org/entity/Q101053716'), ('name', 'Yeheniya Prokofyeva')]
# [('s', 'http://www.wikidata.org/entity/Q27839142'), ('name', 'Kennedy Kimutai')]
# [('s', 'http://www.wikidata.org/entity/Q62711807'), ('name', 'Joan Ramon Moya Garcia')]
# [('s', 'http://www.wikidata.org/entity/Q25160529'), ('name', 'Ben Debognies')]
# [('s', 'http://www.wikidata.org/entity/Q97291064'), ('name', 'Matt Baxter')]
# [('s', 'http://www.wikidata.org/entity/Q722620'), ('name', 'Ismael Kirui')]
# [('s', 'http://www.wikidata.org/entity/Q73758'), ('name', 'Thomas Longosiwa')]
# [('s', 'http://www.wikidata.org/entity/Q711817'), ('name', 'Frederick Lorz')]
# [('s', 'http://www.wikidata.org/entity/Q29733452'), ('name', 'Franjo Škrinjar')]
# [('s', 'http://www.wikidata.org/entity/Q29963919'), ('name', 'Naser Babapour')]
# [('s', 'http://www.wikidata.org/entity/Q29974570'), ('name', 'Vithanakande Samarasinghe')]
# [('s', 'http://www.wikidata.org/entity/Q29995884'), ('name', 'Mariana Ysrael')]
# [('s', 'http://www.wikidata.org/entity/Q14943896'), ('name', 'Yeorjia Abatzidou')]
# [('s', 'http://www.wikidata.org/entity/Q30099624'), ('name', 'Hafida Gadi')]
# [('s', 'http://www.wikidata.org/entity/Q30123005'), ('name', 'Željko Petrović')]
# [('s', 'http://www.wikidata.org/entity/Q63169520'), ('name', 'Cristina Nogué Bori')]
# [('s', 'http://www.wikidata.org/entity/Q44405848'), ('name', 'Mohamed Choumassi')]
# [('s', 'http://www.wikidata.org/entity/Q29997028'), ('name', 'Apollinarie Nyinawabéra')]
# [('s', 'http://www.wikidata.org/entity/Q39336745'), ('name', 'François Willems')]
# [('s', 'http://www.wikidata.org/entity/Q44081622'), ('name', 'Didier Bernard')]
# [('s', 'http://www.wikidata.org/entity/Q11725842'), ('name', 'Jessica Coulson')]
# [('s', 'http://www.wikidata.org/entity/Q96749329'), ('name', 'Emily Brichacek')]
# [('s', 'http://www.wikidata.org/entity/Q96755892'), ('name', 'Angelina Tsere')]
# [('s', 'http://www.wikidata.org/entity/Q96756017'), ('name', 'Rudo Mhonderwa')]
# [('s', 'http://www.wikidata.org/entity/Q96756093'), ('name', 'Natalia Elisante Sulle')]
# [('s', 'http://www.wikidata.org/entity/Q42769552'), ('name', 'Karel Pacák')]
# [('s', 'http://www.wikidata.org/entity/Q43081668'), ('name', 'Ludvík Bombík')]
# [('s', 'http://www.wikidata.org/entity/Q101678865'), ('name', 'Elena Adelina Panaet')]
# [('s', 'http://www.wikidata.org/entity/Q39073573'), ('name', 'Claire McCarthy')]
# [('s', 'http://www.wikidata.org/entity/Q65549672'), ('name', 'Yūka Suzuki')]
# 100

# %%
# aim: get all the subjects related to 'long-distance running' through 'subclass of'
# result: we found all the disciplines related that are involved in 'long-distance running'
queryString = """
SELECT DISTINCT ?s ?name
WHERE {
   # discipline subclass_of long-distance_running
   # ?s wdt:P279 wd:Q917206 .
   # get the label
   # ?s sc:name ?name .
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('s', 'http://www.wikidata.org/entity/Q26844379'), ('name', 'one-hour run')]
# [('s', 'http://www.wikidata.org/entity/Q2815830'), ('name', '2 miles run')]
# [('s', 'http://www.wikidata.org/entity/Q215677'), ('name', 'half marathon')]
# [('s', 'http://www.wikidata.org/entity/Q163892'), ('name', '10,000 metres')]
# [('s', 'http://www.wikidata.org/entity/Q240500'), ('name', '5000 metres')]
# [('s', 'http://www.wikidata.org/entity/Q40244'), ('name', 'marathon')]
# [('s', 'http://www.wikidata.org/entity/Q2774730'), ('name', '10K run')]
# [('s', 'http://www.wikidata.org/entity/Q500050'), ('name', 'cross country running')]
# [('s', 'http://www.wikidata.org/entity/Q26303'), ('name', 'ultramarathon')]
# [('s', 'http://www.wikidata.org/entity/Q2164200'), ('name', 'one hour run')]
# [('s', 'http://www.wikidata.org/entity/Q19767716'), ('name', '15K run')]
# [('s', 'http://www.wikidata.org/entity/Q19827858'), ('name', '20 kilometres')]
# [('s', 'http://www.wikidata.org/entity/Q2538895'), ('name', 'Waffenlauf')]
# 13

# %%
# aim: get all the properties related to 'one-hour run' to find something related to records in this discipline
# result: the empty set is found
queryString = """
SELECT DISTINCT ?p 
WHERE {
   # bind something
   # ?s ?p wd:Q26844379 .
   # get the label
   # ?p sc:name ?name .
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# Empty

# %%
# aim: get all the properties relating 'one-hour run' to other resources to find something related to records in this discipline
# result: we found  'record or record progression'
queryString = """
SELECT DISTINCT ?p ?name
WHERE {
   # bind something
   wd:Q26844379 ?p ?o .
   # get the label
   # ?p sc:name ?name .
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P2869'), ('name', 'record or record progression')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('name', 'subclass of')]
# [('p', 'http://www.wikidata.org/prop/direct/P641'), ('name', 'sport')]
# 3

# %%
# aim: get all the objects related to 'one-hour run' through 'record or record progression'
# result: the empty set is found... We decide to avoid asking for the label to see if the objects have no labels associated
queryString = """
SELECT DISTINCT ?o ?name
WHERE {
   # bind something
   wd:Q26844379 wdt:P2869 ?o .
   # get the label
   # ?o sc:name ?name .
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# Empty

# %%
# aim: get all the objects related to 'one-hour run' through 'record or record progression' without labels
# result: we found 2 objects but we don't know what they are so we must further inspect 
queryString = """
SELECT DISTINCT ?o
WHERE {
   # bind something
   wd:Q26844379 wdt:P2869 ?o .
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('o', 'http://www.wikidata.org/entity/Q16592455')]
# [('o', 'http://www.wikidata.org/entity/Q16592458')]
# 2

# %%
# aim: get all the objects related to 'Q16592455'
# result: we found that it's a list of something (probably records?). Maybe there are athletes correlated to this list so we try to find out if that's true
queryString = """
SELECT DISTINCT ?p ?name
WHERE {
   # bind something
   wd:Q16592455 ?p ?o .
   # get the label
   # ?p sc:name ?name
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('name', 'instance of')]
# [('p', 'http://www.wikidata.org/prop/direct/P360'), ('name', 'is a list of')]
# 2

# %%
# aim: get all the subjects related through some properties to 'Q16592455'
# result: we found just 'record or record progression' that we had already found before. We decide to look for other paths to get records.
queryString = """
SELECT DISTINCT ?s ?sname ?p ?name
WHERE {
   # bind something
    # ?s ?p ?o.
   # ?p sc:name ?name .
   # ?s sc:name ?sname .
   FILTER (?o IN (wd:Q16592455,wd:Q16592458))
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('s', 'http://www.wikidata.org/entity/Q26844379'), ('sname', 'one-hour run'), ('p', 'http://www.wikidata.org/prop/direct/P2869'), ('name', 'record or record progression')]
# 1

# %%
# aim: from the first query about 'Eliud Kipchoge' we found the property 'record held' that might be useful. We try to see what objects is related to it
# result: we found 'Marathon world record progression' which probably means a progressive list of records for the Marathon discipline! We try to check if that's true
queryString = """
SELECT DISTINCT ?obj ?name
WHERE {
   
   wd:Q9124 wdt:P1000 ?obj .
   # get the label
   # ?obj sc:name ?name.
}
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('obj', 'http://www.wikidata.org/entity/Q929585'), ('name', 'Marathon world record progression')]
# 1

# %%
# aim: get all the properties of 'Marathon world record progression'
# result: we found that's actually a list. Maybe there are athletes correlated to it
queryString = """
SELECT DISTINCT ?p ?name
WHERE {
   
   wd:Q929585 ?p ?obj .
   # get the label
   # ?p sc:name ?name.
}
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('name', 'instance of')]
# [('p', 'http://www.wikidata.org/prop/direct/P360'), ('name', 'is a list of')]
# [('p', 'http://www.wikidata.org/prop/direct/P641'), ('name', 'sport')]
# 3

# %%
# aim: get all the properties related to 'Marathon world record progression'
# result: we found 'record held' so we try to see the subjects who held these records
queryString = """
SELECT DISTINCT ?p ?name
WHERE {
   
   # ?s ?p wd:Q929585 .
   # get the label
   # ?p sc:name ?name.
}
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P1000'), ('name', 'record held')]
# 1

# %%
# aim: get all the subjects related to 'Marathon world record progression' through 'record held'
# result: we found the athletes who held a record for the Marathon discipline. There are no dates of when the records were established...
queryString = """
SELECT DISTINCT ?s ?name
WHERE {
   
   # ?s ?p wd:Q929585 .
   # get the label
   # ?s sc:name ?name.
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('s', 'http://www.wikidata.org/entity/Q1044585'), ('name', 'Caroline Walker')]
# [('s', 'http://www.wikidata.org/entity/Q171500'), ('name', 'Gebrselassie Haile')]
# [('s', 'http://www.wikidata.org/entity/Q728634'), ('name', 'Robert de Castella')]
# [('s', 'http://www.wikidata.org/entity/Q9124'), ('name', 'Eliud Kipchoge')]
# [('s', 'http://www.wikidata.org/entity/Q133667'), ('name', 'Sohn Kee-chung')]
# [('s', 'http://www.wikidata.org/entity/Q7635174'), ('name', 'Suh Yun-bok')]
# [('s', 'http://www.wikidata.org/entity/Q1705'), ('name', 'Wilson Kipsang Kiprotich')]
# [('s', 'http://www.wikidata.org/entity/Q518358'), ('name', 'Beth Bonner')]
# [('s', 'http://www.wikidata.org/entity/Q999436'), ('name', 'Morio Shigematsu')]
# [('s', 'http://www.wikidata.org/entity/Q815310'), ('name', 'Belayneh Densamo')]
# [('s', 'http://www.wikidata.org/entity/Q454958'), ('name', 'Carlos Lopes')]
# [('s', 'http://www.wikidata.org/entity/Q456857'), ('name', 'Johnny Hayes')]
# [('s', 'http://www.wikidata.org/entity/Q4710838'), ('name', 'Albert Michelsen')]
# [('s', 'http://www.wikidata.org/entity/Q311338'), ('name', 'Hannes Kolehmainen')]
# [('s', 'http://www.wikidata.org/entity/Q52596'), ('name', 'Abebe Bikila')]
# [('s', 'http://www.wikidata.org/entity/Q63223'), ('name', 'Dennis Kipruto Kimetto')]
# [('s', 'http://www.wikidata.org/entity/Q180891'), ('name', 'Sergei Popov')]
# [('s', 'http://www.wikidata.org/entity/Q313799'), ('name', 'Paul Tergat')]
# [('s', 'http://www.wikidata.org/entity/Q547285'), ('name', 'Anni Pede-Erdkamp')]
# [('s', 'http://www.wikidata.org/entity/Q950340'), ('name', 'Ronaldo da Costa')]
# [('s', 'http://www.wikidata.org/entity/Q428087'), ('name', 'Yasuo Ikenaka')]
# [('s', 'http://www.wikidata.org/entity/Q443382'), ('name', 'Toru Terasawa')]
# [('s', 'http://www.wikidata.org/entity/Q16210614'), ('name', 'Merry Lepper')]
# [('s', 'http://www.wikidata.org/entity/Q5092701'), ('name', 'Cheryl Bridges')]
# [('s', 'http://www.wikidata.org/entity/Q2605754'), ('name', 'Harry Green')]
# [('s', 'http://www.wikidata.org/entity/Q1343502'), ('name', 'Khalid Khannouchi')]
# [('s', 'http://www.wikidata.org/entity/Q7344468'), ('name', 'Robert Fowler')]
# [('s', 'http://www.wikidata.org/entity/Q5543993'), ('name', 'Alexis Ahlgren')]
# [('s', 'http://www.wikidata.org/entity/Q6131368'), ('name', 'James Clark')]
# [('s', 'http://www.wikidata.org/entity/Q7799269'), ('name', 'Thure Johansson')]
# [('s', 'http://www.wikidata.org/entity/Q7933273'), ('name', 'Violet Piercy')]
# [('s', 'http://www.wikidata.org/entity/Q520969'), ('name', 'Miki Gorman')]
# [('s', 'http://www.wikidata.org/entity/Q1001185'), ('name', 'Buddy Edelen')]
# [('s', 'http://www.wikidata.org/entity/Q6851014'), ('name', 'Mildred Sampson')]
# [('s', 'http://www.wikidata.org/entity/Q6792770'), ('name', 'Maureen Wilton')]
# [('s', 'http://www.wikidata.org/entity/Q1200016'), ('name', 'Derek Clayton')]
# [('s', 'http://www.wikidata.org/entity/Q5717831'), ('name', 'Henry Barrett')]
# [('s', 'http://www.wikidata.org/entity/Q810031'), ('name', 'Basil Heatley')]
# [('s', 'http://www.wikidata.org/entity/Q949816'), ('name', 'Jim Peters')]
# [('s', 'http://www.wikidata.org/entity/Q334017'), ('name', 'Patrick Makau Musyoki')]
# [('s', 'http://www.wikidata.org/entity/Q720491'), ('name', 'Steve Jones')]
# [('s', 'http://www.wikidata.org/entity/Q5509922'), ('name', 'Fusashige Suzuki')]
# 42

# %%
# aim: get all the subjects related with 'athletics at the 2004 Summer Olympics' through 'part of' and 'has part'
# result: we found 'athletics at the 2004 Summer Olympics – women's marathon' and 'athletics at the 2004 Summer Olympics – men's marathon'
queryString = """
SELECT DISTINCT ?o ?name
WHERE {
   # bind something
   wd:Q16592455 ?p ?o .
   # get the label
   # ?o sc:name ?name
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('o', 'http://www.wikidata.org/entity/Q13406463'), ('name', 'Wikimedia list article')]
# [('o', 'http://www.wikidata.org/entity/Q24033838'), ('name', "women's world record")]
# 2

# %%
# aim: get all the objects that are superclasses of 'women's world record'
# result: we found 'world record'
queryString = """
SELECT DISTINCT ?o ?name
WHERE {
   # bind something
   wd:Q24033838 wdt:P279 ?o .
   # get the label
   # ?o sc:name ?name
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('o', 'http://www.wikidata.org/entity/Q688615'), ('name', 'world record')]
# 1

# %%
# aim: get all the objects that are 'instance of' 'world record'
# result: we found some world records but not the ones we are looking for
queryString = """
SELECT DISTINCT ?s ?name
WHERE {
   # bind something
   # ?s wdt:P31 wd:Q688615 .
   # get the label
   # ?s sc:name ?name
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('s', 'http://www.wikidata.org/entity/Q1139050'), ('name', "Men's 400 metres hurdles world record progression")]
# [('s', 'http://www.wikidata.org/entity/Q1139195'), ('name', 'decathlon world record progression')]
# [('s', 'http://www.wikidata.org/entity/Q83573'), ('name', "Women's heptathlon world record progression")]
# [('s', 'http://www.wikidata.org/entity/Q1053563'), ('name', "Men's 4 x 400 metres relay world record progression")]
# [('s', 'http://www.wikidata.org/entity/Q1140490'), ('name', "Men's 400 metres world record progression")]
# [('s', 'http://www.wikidata.org/entity/Q30748015'), ('name', "men's 100 metres world record")]
# [('s', 'http://www.wikidata.org/entity/Q70466'), ('name', "Men's discus throw world record progression")]
# [('s', 'http://www.wikidata.org/entity/Q1050464'), ('name', '1500 metres world record progression')]
# [('s', 'http://www.wikidata.org/entity/Q1364158'), ('name', '800 metres world record progression')]
# [('s', 'http://www.wikidata.org/entity/Q95989670'), ('name', "world's longest domestic flight")]
# [('s', 'http://www.wikidata.org/entity/Q107718293'), ('name', 'Marseilles to Carthage')]
# [('s', 'http://www.wikidata.org/entity/Q107769687'), ('name', 'Cowes to Dinard')]
# [('s', 'http://www.wikidata.org/entity/Q83777'), ('name', "Women's 400 metres hurdles world record progression")]
# [('s', 'http://www.wikidata.org/entity/Q3133602'), ('name', '3000 metres steeplechase world record progression')]
# 14

# %%
# aim: get all the objects related with 'Marathon world record progression'
# result: we didn't find anything useful... 'Marathon world record progression' is associated with 'athletics' and not with 'marathon'...
queryString = """
SELECT DISTINCT ?obj ?name
WHERE {
   
   wd:Q929585 ?p ?obj .
   # get the label
   # ?obj sc:name ?name.
}
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('obj', 'http://www.wikidata.org/entity/Q1241356'), ('name', 'record')]
# [('obj', 'http://www.wikidata.org/entity/Q13406463'), ('name', 'Wikimedia list article')]
# [('obj', 'http://www.wikidata.org/entity/Q542'), ('name', 'athletics')]
# [('obj', 'http://www.wikidata.org/entity/Q208410'), ('name', 'List of world records in athletics')]
# 4

# %%
# aim:get all the properties for 'Men's 400 metres hurdles world record progression'
# result: we didn't find something useful
queryString = """
SELECT DISTINCT ?p ?name
WHERE {
   
   # ?s ?p wd:Q1139050 .
   # get the label
   # ?p sc:name ?name.
}
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P2869'), ('name', 'record or record progression')]
# [('p', 'http://www.wikidata.org/prop/direct/P1000'), ('name', 'record held')]
# 2

# %%
# aim: get all the objects related to 'marathon' through 'record held' or 'record or record progression'
# result: we found 2 athletes that are holding the record but not the record progression
queryString = """
SELECT DISTINCT ?o ?name
WHERE {
   # discipline subclass_of long-distance running
   wd:Q40244 wdt:P1000|wdt:P2869 ?o .
   # get the label
   # ?o sc:name ?name .
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('o', 'http://www.wikidata.org/entity/Q9124'), ('name', 'Eliud Kipchoge')]
# [('o', 'http://www.wikidata.org/entity/Q63223'), ('name', 'Dennis Kipruto Kimetto')]
# 2

# %%
# aim: get all the properties of 'Eliud Kipchoge'
# result: did not find any date regarding his/her 'record held'
queryString = """
SELECT DISTINCT ?p ?name
WHERE {
   # discipline subclass_of long-distance running
   wd:Q9124 ?p ?o .
   # get the label
   # ?p sc:name ?name .
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P1000'), ('name', 'record held')]
# [('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('p', 'http://www.wikidata.org/prop/direct/P1146'), ('name', 'World Athletics athlete ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1344'), ('name', 'participant in')]
# [('p', 'http://www.wikidata.org/prop/direct/P1412'), ('name', 'languages spoken, written or signed')]
# [('p', 'http://www.wikidata.org/prop/direct/P1447'), ('name', 'Sports-Reference.com Olympic athlete ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1532'), ('name', 'country for sport')]
# [('p', 'http://www.wikidata.org/prop/direct/P1559'), ('name', 'name in native language')]
# [('p', 'http://www.wikidata.org/prop/direct/P172'), ('name', 'ethnic group')]
# [('p', 'http://www.wikidata.org/prop/direct/P1741'), ('name', 'GTAA ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P18'), ('name', 'image')]
# [('p', 'http://www.wikidata.org/prop/direct/P19'), ('name', 'place of birth')]
# [('p', 'http://www.wikidata.org/prop/direct/P2002'), ('name', 'Twitter username')]
# [('p', 'http://www.wikidata.org/prop/direct/P2003'), ('name', 'Instagram username')]
# [('p', 'http://www.wikidata.org/prop/direct/P2013'), ('name', 'Facebook ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2048'), ('name', 'height')]
# [('p', 'http://www.wikidata.org/prop/direct/P2067'), ('name', 'mass')]
# [('p', 'http://www.wikidata.org/prop/direct/P21'), ('name', 'sex or gender')]
# [('p', 'http://www.wikidata.org/prop/direct/P214'), ('name', 'VIAF ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P227'), ('name', 'GND ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2416'), ('name', 'sports discipline competed in')]
# [('p', 'http://www.wikidata.org/prop/direct/P27'), ('name', 'country of citizenship')]
# [('p', 'http://www.wikidata.org/prop/direct/P286'), ('name', 'head coach')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('name', 'instance of')]
# [('p', 'http://www.wikidata.org/prop/direct/P3171'), ('name', 'Olympic.org athlete ID (archived version)')]
# [('p', 'http://www.wikidata.org/prop/direct/P3520'), ('name', 'databaseOlympics.com athlete ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P373'), ('name', 'Commons category')]
# [('p', 'http://www.wikidata.org/prop/direct/P3765'), ('name', 'All-Athletics.com ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3884'), ('name', 'Tilastopaja male athlete ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3923'), ('name', 'Diamond League athlete ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3925'), ('name', 'Track and Field Statistics male athlete ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P4548'), ('name', 'Commonwealth Games Federation athlete ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P569'), ('name', 'date of birth')]
# [('p', 'http://www.wikidata.org/prop/direct/P5815'), ('name', 'Olympics.com athlete ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P641'), ('name', 'sport')]
# [('p', 'http://www.wikidata.org/prop/direct/P646'), ('name', 'Freebase ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7293'), ('name', 'PLWABN ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P734'), ('name', 'family name')]
# [('p', 'http://www.wikidata.org/prop/direct/P735'), ('name', 'given name')]
# [('p', 'http://www.wikidata.org/prop/direct/P7859'), ('name', 'WorldCat Identities ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8286'), ('name', 'Olympedia people ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8687'), ('name', 'social media followers')]
# [('p', 'http://www.wikidata.org/prop/direct/P2415'), ('name', 'personal best')]
# 43

# %%
# aim: get all the progressions that could match the subclasses of 'long-distance running' through regexes
# result: we found some of them, we try to increase the "range" of the regex
queryString = """
SELECT DISTINCT ?progression ?progressionname
WHERE {
   
   # ?s wdt:P1000|wdt:P2869 ?progression .
   # get the label
   # ?s sc:name ?name.
   # ?progression sc:name ?progressionname
   FILTER REGEX(?progressionname,"marathon|10000|10K|5K|5000|one hour|one-hour|cross country","i").
   FILTER REGEX(?progressionname,"progression","i").
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('progression', 'http://www.wikidata.org/entity/Q17069829'), ('progressionname', '5000 metres world record progression')]
# [('progression', 'http://www.wikidata.org/entity/Q3922786'), ('progressionname', "Men's 5000 metres world record progression")]
# [('progression', 'http://www.wikidata.org/entity/Q3922787'), ('progressionname', "Women's 5000 metres world record progression")]
# [('progression', 'http://www.wikidata.org/entity/Q929585'), ('progressionname', 'Marathon world record progression')]
# [('progression', 'http://www.wikidata.org/entity/Q875819'), ('progressionname', 'World record progression 5000 m speed skating women')]
# [('progression', 'http://www.wikidata.org/entity/Q1054893'), ('progressionname', 'World record progression 5000 m speed skating men')]
# [('progression', 'http://www.wikidata.org/entity/Q1054902'), ('progressionname', 'World record progression 10000 m speed skating men')]
# 7

# %%
# aim: get all the progressions that could match the subclasses of 'long-distance running' through regexes
# result: we found some of them, we try to increase the "range" of the regex
queryString = """
SELECT DISTINCT ?progression ?progressionname
WHERE {
   
   # ?s wdt:P1000|wdt:P2869 ?progression .
   # get the label
   # ?s sc:name ?name.
   # ?progression sc:name ?progressionname
   FILTER REGEX(?progressionname,"marathon|10000|10,000|10K|5K|5000|one hour|one-hour|cross country|2 miles","i").
   FILTER REGEX(?progressionname,"progression","i").
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('progression', 'http://www.wikidata.org/entity/Q16714855'), ('progressionname', '10,000 metres world record progression')]
# [('progression', 'http://www.wikidata.org/entity/Q17069829'), ('progressionname', '5000 metres world record progression')]
# [('progression', 'http://www.wikidata.org/entity/Q3922786'), ('progressionname', "Men's 5000 metres world record progression")]
# [('progression', 'http://www.wikidata.org/entity/Q3922787'), ('progressionname', "Women's 5000 metres world record progression")]
# [('progression', 'http://www.wikidata.org/entity/Q929585'), ('progressionname', 'Marathon world record progression')]
# [('progression', 'http://www.wikidata.org/entity/Q875819'), ('progressionname', 'World record progression 5000 m speed skating women')]
# [('progression', 'http://www.wikidata.org/entity/Q1054893'), ('progressionname', 'World record progression 5000 m speed skating men')]
# [('progression', 'http://www.wikidata.org/entity/Q1054902'), ('progressionname', 'World record progression 10000 m speed skating men')]
# 8

# %%
# aim: get all the progressions that could match the subclasses of 'long-distance running' through regexes
# result: we found just the record progressions of 5000 metres,10000 metres and marathon. We manually have to match the progressions with the sports and finally return all the
#         athletes that held a record for that sport as the final query
queryString = """
SELECT DISTINCT ?progression ?progressionname
WHERE {
   
   # ?s wdt:P1000|wdt:P2869 ?progression .
   # get the label
   # ?s sc:name ?name.
   # ?progression sc:name ?progressionname .
   FILTER REGEX(?progressionname,"marathon|10000|10,000|10K|5K|5000|one hour|one-hour|cross country|2 miles|20 kilometers|20,000|20000|15K|15,0000|Waffenlauf|2|1","i").
   FILTER REGEX(?progressionname,"progression","i").
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('progression', 'http://www.wikidata.org/entity/Q1135532'), ('progressionname', 'World record progression 4 × 100 metres freestyle relay')]
# [('progression', 'http://www.wikidata.org/entity/Q83583'), ('progressionname', "Women's 20 kilometres walk world record progression")]
# [('progression', 'http://www.wikidata.org/entity/Q1188561'), ('progressionname', 'World record progression 4 × 100 metres medley relay')]
# [('progression', 'http://www.wikidata.org/entity/Q1050464'), ('progressionname', '1500 metres world record progression')]
# [('progression', 'http://www.wikidata.org/entity/Q1066353'), ('progressionname', "Men's 100 metres world record progression")]
# [('progression', 'http://www.wikidata.org/entity/Q1316690'), ('progressionname', "Women's 100 metres world record progression")]
# [('progression', 'http://www.wikidata.org/entity/Q1187829'), ('progressionname', "men's 200 metres world record progression")]
# [('progression', 'http://www.wikidata.org/entity/Q1050432'), ('progressionname', "Women's 200 metres world record progression")]
# [('progression', 'http://www.wikidata.org/entity/Q124599'), ('progressionname', "Women's 4 × 100 metres relay world record progression")]
# [('progression', 'http://www.wikidata.org/entity/Q1053804'), ('progressionname', "Men's 4 × 100 metres relay world record progression")]
# [('progression', 'http://www.wikidata.org/entity/Q1136298'), ('progressionname', "Men's 110 metres hurdles world record progression")]
# [('progression', 'http://www.wikidata.org/entity/Q1316274'), ('progressionname', 'World record progression 1500 metres freestyle')]
# [('progression', 'http://www.wikidata.org/entity/Q16714855'), ('progressionname', '10,000 metres world record progression')]
# [('progression', 'http://www.wikidata.org/entity/Q17069829'), ('progressionname', '5000 metres world record progression')]
# [('progression', 'http://www.wikidata.org/entity/Q3922786'), ('progressionname', "Men's 5000 metres world record progression")]
# [('progression', 'http://www.wikidata.org/entity/Q3922787'), ('progressionname', "Women's 5000 metres world record progression")]
# [('progression', 'http://www.wikidata.org/entity/Q929585'), ('progressionname', 'Marathon world record progression')]
# [('progression', 'http://www.wikidata.org/entity/Q1186753'), ('progressionname', 'World record progression 100 metres butterfly')]
# [('progression', 'http://www.wikidata.org/entity/Q13423106'), ('progressionname', '1000 metres world record progression')]
# [('progression', 'http://www.wikidata.org/entity/Q1055256'), ('progressionname', 'World record progression 1500 m speed skating men')]
# [('progression', 'http://www.wikidata.org/entity/Q1055267'), ('progressionname', 'world record progression 1500 m speed skating women')]
# [('progression', 'http://www.wikidata.org/entity/Q1362958'), ('progressionname', 'World record progression 200 metres freestyle')]
# [('progression', 'http://www.wikidata.org/entity/Q1135718'), ('progressionname', 'World record progression 4 × 200 metres freestyle relay')]
# [('progression', 'http://www.wikidata.org/entity/Q3422413'), ('progressionname', "Women's 100 metres hurdles world record progression")]
# [('progression', 'http://www.wikidata.org/entity/Q3422175'), ('progressionname', "Men's 200 metres European record progression")]
# [('progression', 'http://www.wikidata.org/entity/Q174625'), ('progressionname', 'World record progression 200 metres butterfly')]
# [('progression', 'http://www.wikidata.org/entity/Q83581'), ('progressionname', "Women's 10 kilometres walk world record progression")]
# [('progression', 'http://www.wikidata.org/entity/Q1054957'), ('progressionname', 'World record progression 1000 m speed skating women')]
# [('progression', 'http://www.wikidata.org/entity/Q1054882'), ('progressionname', 'World record progression 1000 m speed skating men')]
# [('progression', 'http://www.wikidata.org/entity/Q785673'), ('progressionname', 'World record progression 100 metres individual medley')]
# [('progression', 'http://www.wikidata.org/entity/Q742645'), ('progressionname', 'World record progression 200 metres backstroke')]
# [('progression', 'http://www.wikidata.org/entity/Q20312914'), ('progressionname', "Men's 4 x 200 metres relay world record progression")]
# [('progression', 'http://www.wikidata.org/entity/Q875819'), ('progressionname', 'World record progression 5000 m speed skating women')]
# [('progression', 'http://www.wikidata.org/entity/Q1054893'), ('progressionname', 'World record progression 5000 m speed skating men')]
# [('progression', 'http://www.wikidata.org/entity/Q1054902'), ('progressionname', 'World record progression 10000 m speed skating men')]
# [('progression', 'http://www.wikidata.org/entity/Q1187950'), ('progressionname', 'world record progression 100 metres backstroke')]
# [('progression', 'http://www.wikidata.org/entity/Q925859'), ('progressionname', 'World record progression 200 metres breaststroke')]
# [('progression', 'http://www.wikidata.org/entity/Q1202761'), ('progressionname', 'World record progression 100 metres freestyle')]
# [('progression', 'http://www.wikidata.org/entity/Q1364184'), ('progressionname', 'world record progression 100 metres breaststroke')]
# [('progression', 'http://www.wikidata.org/entity/Q1187060'), ('progressionname', 'World record progression 200 metres individual medley')]
# 40

# %%
# aim: get all the athletes who held a record in the marathon discipline
# result: the athletes who held a record in the marathon discipline
queryString = """
SELECT DISTINCT (wd:Q40244 as ?discipline) ?disciplinename ?athlete ?athletename
WHERE {
   wd:Q40244 sc:name ?disciplinename .
   # ?athlete wdt:P1000 wd:Q929585 .
   # get the label
   # ?athlete sc:name ?athletename.
}
LIMIT 5
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('discipline', 'http://www.wikidata.org/entity/Q40244'), ('disciplinename', 'marathon'), ('athlete', 'http://www.wikidata.org/entity/Q1044585'), ('athletename', 'Caroline Walker')]
# [('discipline', 'http://www.wikidata.org/entity/Q40244'), ('disciplinename', 'marathon'), ('athlete', 'http://www.wikidata.org/entity/Q171500'), ('athletename', 'Gebrselassie Haile')]
# [('discipline', 'http://www.wikidata.org/entity/Q40244'), ('disciplinename', 'marathon'), ('athlete', 'http://www.wikidata.org/entity/Q728634'), ('athletename', 'Robert de Castella')]
# [('discipline', 'http://www.wikidata.org/entity/Q40244'), ('disciplinename', 'marathon'), ('athlete', 'http://www.wikidata.org/entity/Q9124'), ('athletename', 'Eliud Kipchoge')]
# [('discipline', 'http://www.wikidata.org/entity/Q40244'), ('disciplinename', 'marathon'), ('athlete', 'http://www.wikidata.org/entity/Q133667'), ('athletename', 'Sohn Kee-chung')]
# 5

# %%
# aim: get all the athletes who held a record in the marathon,10000 metres and 5000 metres disciplines
# result: the athletes who held a record in the marathon discipline. The other records must be found in other ways...
queryString = """
SELECT DISTINCT ?discipline ?disciplinename ?athlete ?athletename
WHERE {
    {
        # athletes who held a record for the marathon
        SELECT DISTINCT (wd:Q40244 as ?discipline) ?disciplinename ?athlete ?athletename WHERE
        {
           wd:Q40244 sc:name ?disciplinename .
           # ?athlete wdt:P1000 wd:Q929585 .
           # get the label
           # ?athlete sc:name ?athletename.
        }
    }
    UNION
    {
        # athletes who held a record for the 10000 metres 
        SELECT DISTINCT (wd:Q163892 as ?discipline) ?disciplinename ?athlete ?athletename WHERE
        {
           wd:Q163892 sc:name ?disciplinename .
           # ?athlete wdt:P1000 wd:Q16714855 .
           # get the label
           # ?athlete sc:name ?athletename.
        }
    
    }
    UNION
    {
        # athletes who held a record for the 5000 metres 
        SELECT DISTINCT (wd:Q240500 as ?discipline) ?disciplinename ?athlete ?athletename WHERE
        {
           wd:Q240500 sc:name ?disciplinename .
           # ?athlete wdt:P1000 wd:Q17069829 .
           # get the label
           # ?athlete sc:name ?athletename.
        }
    
    }
}
LIMIT 150
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('discipline', 'http://www.wikidata.org/entity/Q40244'), ('disciplinename', 'marathon'), ('athlete', 'http://www.wikidata.org/entity/Q1044585'), ('athletename', 'Caroline Walker')]
# [('discipline', 'http://www.wikidata.org/entity/Q40244'), ('disciplinename', 'marathon'), ('athlete', 'http://www.wikidata.org/entity/Q171500'), ('athletename', 'Gebrselassie Haile')]
# [('discipline', 'http://www.wikidata.org/entity/Q40244'), ('disciplinename', 'marathon'), ('athlete', 'http://www.wikidata.org/entity/Q728634'), ('athletename', 'Robert de Castella')]
# [('discipline', 'http://www.wikidata.org/entity/Q40244'), ('disciplinename', 'marathon'), ('athlete', 'http://www.wikidata.org/entity/Q9124'), ('athletename', 'Eliud Kipchoge')]
# [('discipline', 'http://www.wikidata.org/entity/Q40244'), ('disciplinename', 'marathon'), ('athlete', 'http://www.wikidata.org/entity/Q133667'), ('athletename', 'Sohn Kee-chung')]
# [('discipline', 'http://www.wikidata.org/entity/Q40244'), ('disciplinename', 'marathon'), ('athlete', 'http://www.wikidata.org/entity/Q7635174'), ('athletename', 'Suh Yun-bok')]
# [('discipline', 'http://www.wikidata.org/entity/Q40244'), ('disciplinename', 'marathon'), ('athlete', 'http://www.wikidata.org/entity/Q1705'), ('athletename', 'Wilson Kipsang Kiprotich')]
# [('discipline', 'http://www.wikidata.org/entity/Q40244'), ('disciplinename', 'marathon'), ('athlete', 'http://www.wikidata.org/entity/Q518358'), ('athletename', 'Beth Bonner')]
# [('discipline', 'http://www.wikidata.org/entity/Q40244'), ('disciplinename', 'marathon'), ('athlete', 'http://www.wikidata.org/entity/Q999436'), ('athletename', 'Morio Shigematsu')]
# [('discipline', 'http://www.wikidata.org/entity/Q40244'), ('disciplinename', 'marathon'), ('athlete', 'http://www.wikidata.org/entity/Q815310'), ('athletename', 'Belayneh Densamo')]
# [('discipline', 'http://www.wikidata.org/entity/Q40244'), ('disciplinename', 'marathon'), ('athlete', 'http://www.wikidata.org/entity/Q454958'), ('athletename', 'Carlos Lopes')]
# [('discipline', 'http://www.wikidata.org/entity/Q40244'), ('disciplinename', 'marathon'), ('athlete', 'http://www.wikidata.org/entity/Q456857'), ('athletename', 'Johnny Hayes')]
# [('discipline', 'http://www.wikidata.org/entity/Q40244'), ('disciplinename', 'marathon'), ('athlete', 'http://www.wikidata.org/entity/Q4710838'), ('athletename', 'Albert Michelsen')]
# [('discipline', 'http://www.wikidata.org/entity/Q40244'), ('disciplinename', 'marathon'), ('athlete', 'http://www.wikidata.org/entity/Q311338'), ('athletename', 'Hannes Kolehmainen')]
# [('discipline', 'http://www.wikidata.org/entity/Q40244'), ('disciplinename', 'marathon'), ('athlete', 'http://www.wikidata.org/entity/Q52596'), ('athletename', 'Abebe Bikila')]
# [('discipline', 'http://www.wikidata.org/entity/Q40244'), ('disciplinename', 'marathon'), ('athlete', 'http://www.wikidata.org/entity/Q63223'), ('athletename', 'Dennis Kipruto Kimetto')]
# [('discipline', 'http://www.wikidata.org/entity/Q40244'), ('disciplinename', 'marathon'), ('athlete', 'http://www.wikidata.org/entity/Q180891'), ('athletename', 'Sergei Popov')]
# [('discipline', 'http://www.wikidata.org/entity/Q40244'), ('disciplinename', 'marathon'), ('athlete', 'http://www.wikidata.org/entity/Q313799'), ('athletename', 'Paul Tergat')]
# [('discipline', 'http://www.wikidata.org/entity/Q40244'), ('disciplinename', 'marathon'), ('athlete', 'http://www.wikidata.org/entity/Q547285'), ('athletename', 'Anni Pede-Erdkamp')]
# [('discipline', 'http://www.wikidata.org/entity/Q40244'), ('disciplinename', 'marathon'), ('athlete', 'http://www.wikidata.org/entity/Q950340'), ('athletename', 'Ronaldo da Costa')]
# [('discipline', 'http://www.wikidata.org/entity/Q40244'), ('disciplinename', 'marathon'), ('athlete', 'http://www.wikidata.org/entity/Q428087'), ('athletename', 'Yasuo Ikenaka')]
# [('discipline', 'http://www.wikidata.org/entity/Q40244'), ('disciplinename', 'marathon'), ('athlete', 'http://www.wikidata.org/entity/Q443382'), ('athletename', 'Toru Terasawa')]
# [('discipline', 'http://www.wikidata.org/entity/Q40244'), ('disciplinename', 'marathon'), ('athlete', 'http://www.wikidata.org/entity/Q16210614'), ('athletename', 'Merry Lepper')]
# [('discipline', 'http://www.wikidata.org/entity/Q40244'), ('disciplinename', 'marathon'), ('athlete', 'http://www.wikidata.org/entity/Q5092701'), ('athletename', 'Cheryl Bridges')]
# [('discipline', 'http://www.wikidata.org/entity/Q40244'), ('disciplinename', 'marathon'), ('athlete', 'http://www.wikidata.org/entity/Q2605754'), ('athletename', 'Harry Green')]
# [('discipline', 'http://www.wikidata.org/entity/Q40244'), ('disciplinename', 'marathon'), ('athlete', 'http://www.wikidata.org/entity/Q1343502'), ('athletename', 'Khalid Khannouchi')]
# [('discipline', 'http://www.wikidata.org/entity/Q40244'), ('disciplinename', 'marathon'), ('athlete', 'http://www.wikidata.org/entity/Q7344468'), ('athletename', 'Robert Fowler')]
# [('discipline', 'http://www.wikidata.org/entity/Q40244'), ('disciplinename', 'marathon'), ('athlete', 'http://www.wikidata.org/entity/Q5543993'), ('athletename', 'Alexis Ahlgren')]
# [('discipline', 'http://www.wikidata.org/entity/Q40244'), ('disciplinename', 'marathon'), ('athlete', 'http://www.wikidata.org/entity/Q6131368'), ('athletename', 'James Clark')]
# [('discipline', 'http://www.wikidata.org/entity/Q40244'), ('disciplinename', 'marathon'), ('athlete', 'http://www.wikidata.org/entity/Q7799269'), ('athletename', 'Thure Johansson')]
# [('discipline', 'http://www.wikidata.org/entity/Q40244'), ('disciplinename', 'marathon'), ('athlete', 'http://www.wikidata.org/entity/Q7933273'), ('athletename', 'Violet Piercy')]
# [('discipline', 'http://www.wikidata.org/entity/Q40244'), ('disciplinename', 'marathon'), ('athlete', 'http://www.wikidata.org/entity/Q520969'), ('athletename', 'Miki Gorman')]
# [('discipline', 'http://www.wikidata.org/entity/Q40244'), ('disciplinename', 'marathon'), ('athlete', 'http://www.wikidata.org/entity/Q1001185'), ('athletename', 'Buddy Edelen')]
# [('discipline', 'http://www.wikidata.org/entity/Q40244'), ('disciplinename', 'marathon'), ('athlete', 'http://www.wikidata.org/entity/Q6851014'), ('athletename', 'Mildred Sampson')]
# [('discipline', 'http://www.wikidata.org/entity/Q40244'), ('disciplinename', 'marathon'), ('athlete', 'http://www.wikidata.org/entity/Q6792770'), ('athletename', 'Maureen Wilton')]
# [('discipline', 'http://www.wikidata.org/entity/Q40244'), ('disciplinename', 'marathon'), ('athlete', 'http://www.wikidata.org/entity/Q1200016'), ('athletename', 'Derek Clayton')]
# [('discipline', 'http://www.wikidata.org/entity/Q40244'), ('disciplinename', 'marathon'), ('athlete', 'http://www.wikidata.org/entity/Q5717831'), ('athletename', 'Henry Barrett')]
# [('discipline', 'http://www.wikidata.org/entity/Q40244'), ('disciplinename', 'marathon'), ('athlete', 'http://www.wikidata.org/entity/Q810031'), ('athletename', 'Basil Heatley')]
# [('discipline', 'http://www.wikidata.org/entity/Q40244'), ('disciplinename', 'marathon'), ('athlete', 'http://www.wikidata.org/entity/Q949816'), ('athletename', 'Jim Peters')]
# [('discipline', 'http://www.wikidata.org/entity/Q40244'), ('disciplinename', 'marathon'), ('athlete', 'http://www.wikidata.org/entity/Q334017'), ('athletename', 'Patrick Makau Musyoki')]
# [('discipline', 'http://www.wikidata.org/entity/Q40244'), ('disciplinename', 'marathon'), ('athlete', 'http://www.wikidata.org/entity/Q720491'), ('athletename', 'Steve Jones')]
# [('discipline', 'http://www.wikidata.org/entity/Q40244'), ('disciplinename', 'marathon'), ('athlete', 'http://www.wikidata.org/entity/Q5509922'), ('athletename', 'Fusashige Suzuki')]
# 42

# %%
# aim: get all the properties related to '10,000 metres world record progression'
# result: 'record or record progression' is found
queryString = """
SELECT DISTINCT ?p ?pname
WHERE {
   # ?s ?p wd:Q16714855 .
   # get the label
   # ?p sc:name ?pname.
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P2869'), ('pname', 'record or record progression')]
# 1

# %%
# aim: get all the athletes who held a record for the '10,000 metres world record progression'
# result: no athletes have been found... we need to check all the properties of '10,000 metres'
queryString = """
SELECT DISTINCT ?s ?sname
WHERE {
   # ?s ?p wd:Q16714855 .
   # get the label
   # ?s sc:name ?sname.
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('s', 'http://www.wikidata.org/entity/Q163892'), ('sname', '10,000 metres')]
# 1

# %%
# aim: get all the properties of '10,000 metres'
# result: 'statistical leader' has been found
queryString = """
SELECT DISTINCT ?p ?pname
WHERE {
   wd:Q163892 ?p ?o .
   # get the label
   # ?p sc:name ?pname.
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P2869'), ('pname', 'record or record progression')]
# [('p', 'http://www.wikidata.org/prop/direct/P1417'), ('pname', 'Encyclopædia Britannica Online ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2581'), ('pname', 'BabelNet ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pname', 'subclass of')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pname', 'instance of')]
# [('p', 'http://www.wikidata.org/prop/direct/P641'), ('pname', 'sport')]
# [('p', 'http://www.wikidata.org/prop/direct/P646'), ('pname', 'Freebase ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P910'), ('pname', "topic's main category")]
# [('p', 'http://www.wikidata.org/prop/direct/P3279'), ('pname', 'statistical leader')]
# 9

# %%
# aim: get all the 'statistical leader's related to '10,000 metres'
# result: 'Kenenisa Bekele Beyecha' has been found
queryString = """
SELECT DISTINCT ?o ?oname
WHERE {
   wd:Q163892 wdt:P3279 ?o .
   # get the label
   # ?o sc:name ?oname.
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('o', 'http://www.wikidata.org/entity/Q9119'), ('oname', 'Kenenisa Bekele Beyecha')]
# 1

# %%
# aim: get all the properties of 'Kenenisa Bekele Beyecha'
# result: 'record held' has been found
queryString = """
SELECT DISTINCT ?p ?pname
WHERE {
   wd:Q9119 ?p ?o .
   # get the label
   # ?p sc:name ?pname.
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P1000'), ('pname', 'record held')]
# [('p', 'http://www.wikidata.org/prop/direct/P106'), ('pname', 'occupation')]
# [('p', 'http://www.wikidata.org/prop/direct/P1146'), ('pname', 'World Athletics athlete ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1285'), ('pname', 'Munzinger Sport number')]
# [('p', 'http://www.wikidata.org/prop/direct/P1296'), ('pname', 'Gran Enciclopèdia Catalana ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1343'), ('pname', 'described by source')]
# [('p', 'http://www.wikidata.org/prop/direct/P1344'), ('pname', 'participant in')]
# [('p', 'http://www.wikidata.org/prop/direct/P1417'), ('pname', 'Encyclopædia Britannica Online ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1447'), ('pname', 'Sports-Reference.com Olympic athlete ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P166'), ('pname', 'award received')]
# [('p', 'http://www.wikidata.org/prop/direct/P1741'), ('pname', 'GTAA ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P18'), ('pname', 'image')]
# [('p', 'http://www.wikidata.org/prop/direct/P19'), ('pname', 'place of birth')]
# [('p', 'http://www.wikidata.org/prop/direct/P2003'), ('pname', 'Instagram username')]
# [('p', 'http://www.wikidata.org/prop/direct/P2048'), ('pname', 'height')]
# [('p', 'http://www.wikidata.org/prop/direct/P2067'), ('pname', 'mass')]
# [('p', 'http://www.wikidata.org/prop/direct/P21'), ('pname', 'sex or gender')]
# [('p', 'http://www.wikidata.org/prop/direct/P2416'), ('pname', 'sports discipline competed in')]
# [('p', 'http://www.wikidata.org/prop/direct/P27'), ('pname', 'country of citizenship')]
# [('p', 'http://www.wikidata.org/prop/direct/P2924'), ('pname', 'Great Russian Encyclopedia Online ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pname', 'instance of')]
# [('p', 'http://www.wikidata.org/prop/direct/P3171'), ('pname', 'Olympic.org athlete ID (archived version)')]
# [('p', 'http://www.wikidata.org/prop/direct/P3219'), ('pname', 'Encyclopædia Universalis ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P373'), ('pname', 'Commons category')]
# [('p', 'http://www.wikidata.org/prop/direct/P3765'), ('pname', 'All-Athletics.com ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3923'), ('pname', 'Diamond League athlete ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3925'), ('pname', 'Track and Field Statistics male athlete ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P4342'), ('pname', 'Store norske leksikon ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5019'), ('pname', 'Brockhaus Enzyklopädie online ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P569'), ('pname', 'date of birth')]
# [('p', 'http://www.wikidata.org/prop/direct/P5815'), ('pname', 'Olympics.com athlete ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P641'), ('pname', 'sport')]
# [('p', 'http://www.wikidata.org/prop/direct/P646'), ('pname', 'Freebase ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8286'), ('pname', 'Olympedia people ID')]
# 34

# %%
# aim: get all the objects related to 'Kenenisa Bekele Beyecha' through 'record held'
# result: we found that for '5000 metres' and '10,000 metres' the records are stored differently with respect to the 'marathon' ones. We need to check if there
#         is a statistical leader also for 'marathon'
queryString = """
SELECT DISTINCT ?o ?oname
WHERE {
   wd:Q9119 wdt:P1000 ?o .
   # get the label
   # ?o sc:name ?oname.
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('o', 'http://www.wikidata.org/entity/Q240500'), ('oname', '5000 metres')]
# [('o', 'http://www.wikidata.org/entity/Q52159822'), ('oname', "men's 10,000 meters world record in track and field")]
# 2

# %%
# aim: get all the properties of 'marathon'
# result: 'statistical leader' has not been found but we found 'record held'. if there is only one athlete maybe he/she is the last one holding a record
queryString = """
SELECT DISTINCT ?p ?pname
WHERE {
   wd:Q40244 ?p ?o .
   # get the label
   # ?p sc:name ?pname.
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P1000'), ('pname', 'record held')]
# [('p', 'http://www.wikidata.org/prop/direct/P1225'), ('pname', 'U.S. National Archives Identifier')]
# [('p', 'http://www.wikidata.org/prop/direct/P1245'), ('pname', 'OmegaWiki Defined Meaning')]
# [('p', 'http://www.wikidata.org/prop/direct/P1296'), ('pname', 'Gran Enciclopèdia Catalana ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1343'), ('pname', 'described by source')]
# [('p', 'http://www.wikidata.org/prop/direct/P138'), ('pname', 'named after')]
# [('p', 'http://www.wikidata.org/prop/direct/P1417'), ('pname', 'Encyclopædia Britannica Online ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P18'), ('pname', 'image')]
# [('p', 'http://www.wikidata.org/prop/direct/P227'), ('pname', 'GND ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2347'), ('pname', 'YSO ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P244'), ('pname', 'Library of Congress authority ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2581'), ('pname', 'BabelNet ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P268'), ('pname', 'Bibliothèque nationale de France ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pname', 'subclass of')]
# [('p', 'http://www.wikidata.org/prop/direct/P2924'), ('pname', 'Great Russian Encyclopedia Online ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3095'), ('pname', 'practiced by')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pname', 'instance of')]
# [('p', 'http://www.wikidata.org/prop/direct/P3157'), ('pname', 'event distance')]
# [('p', 'http://www.wikidata.org/prop/direct/P3219'), ('pname', 'Encyclopædia Universalis ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3221'), ('pname', 'New York Times topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3417'), ('pname', 'Quora topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P349'), ('pname', 'National Diet Library ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3553'), ('pname', 'Zhihu topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3827'), ('pname', 'JSTOR topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P4613'), ('pname', 'Encyclopedia of Modern Ukraine ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P508'), ('pname', 'BNCF Thesaurus ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5429'), ('pname', 'IPTC NewsCode')]
# [('p', 'http://www.wikidata.org/prop/direct/P5513'), ('pname', "Enciclopèdia de l'Esport Català ID")]
# [('p', 'http://www.wikidata.org/prop/direct/P641'), ('pname', 'sport')]
# [('p', 'http://www.wikidata.org/prop/direct/P646'), ('pname', 'Freebase ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6573'), ('pname', 'Klexikon article ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7818'), ('pname', 'French Vikidia ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8408'), ('pname', 'KBpedia ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8672'), ('pname', 'Twitter topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P910'), ('pname', "topic's main category")]
# [('p', 'http://www.wikidata.org/prop/direct/P948'), ('pname', 'page banner')]
# [('p', 'http://www.wikidata.org/prop/direct/P9873'), ('pname', 'Enciclopedia dello Sport ID')]
# 37

# %%
# aim: get all the objects related to 'marathon' through 'record held'
# result: we found 2 athletes holding a record
queryString = """
SELECT DISTINCT ?o ?oname
WHERE {
   wd:Q40244 wdt:P1000 ?o .
   # get the label
   # ?o sc:name ?oname.
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('o', 'http://www.wikidata.org/entity/Q9124'), ('oname', 'Eliud Kipchoge')]
# [('o', 'http://www.wikidata.org/entity/Q63223'), ('oname', 'Dennis Kipruto Kimetto')]
# 2

# %%
# aim: get all the records that could match the subclasses of 'long-distance running' through regexes having at least a 'record held' property connected
# result: all the records or progressions that could match the subclasses of 'long-distance running' through regexes having at least a 'record held' property connected
queryString = """
SELECT DISTINCT ?record ?recordname
WHERE {
   
   # ?s wdt:P1000 ?record .
   # get the label
   # ?record sc:name ?recordname.
   FILTER REGEX(?recordname,"marathon|10000|10,000|10K|5K|5000|one hour|one-hour|cross country|2 miles|20 kilometers|20,000|20000|15K|15,0000|Waffenlauf|2|1|kilometers|km","i").
}
LIMIT 300
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('record', 'http://www.wikidata.org/entity/Q164761'), ('recordname', '100 metres')]
# [('record', 'http://www.wikidata.org/entity/Q211155'), ('recordname', '200 metres')]
# [('record', 'http://www.wikidata.org/entity/Q1066353'), ('recordname', "Men's 100 metres world record progression")]
# [('record', 'http://www.wikidata.org/entity/Q1316690'), ('recordname', "Women's 100 metres world record progression")]
# [('record', 'http://www.wikidata.org/entity/Q1316274'), ('recordname', 'World record progression 1500 metres freestyle')]
# [('record', 'http://www.wikidata.org/entity/Q163892'), ('recordname', '10,000 metres')]
# [('record', 'http://www.wikidata.org/entity/Q191691'), ('recordname', '1500 metres')]
# [('record', 'http://www.wikidata.org/entity/Q240500'), ('recordname', '5000 metres')]
# [('record', 'http://www.wikidata.org/entity/Q52159822'), ('recordname', "men's 10,000 meters world record in track and field")]
# [('record', 'http://www.wikidata.org/entity/Q9171043'), ('recordname', '5K run')]
# [('record', 'http://www.wikidata.org/entity/Q929585'), ('recordname', 'Marathon world record progression')]
# [('record', 'http://www.wikidata.org/entity/Q1135718'), ('recordname', 'World record progression 4 × 200 metres freestyle relay')]
# [('record', 'http://www.wikidata.org/entity/Q9130693'), ('recordname', '200 metres backstroke')]
# [('record', 'http://www.wikidata.org/entity/Q19962532'), ('recordname', 'most fatalities in an aviation incident aboard a Boeing 720')]
# [('record', 'http://www.wikidata.org/entity/Q30748015'), ('recordname', "men's 100 metres world record")]
# [('record', 'http://www.wikidata.org/entity/Q2164200'), ('recordname', 'one hour run')]
# [('record', 'http://www.wikidata.org/entity/Q3422413'), ('recordname', "Women's 100 metres hurdles world record progression")]
# [('record', 'http://www.wikidata.org/entity/Q1050464'), ('recordname', '1500 metres world record progression')]
# [('record', 'http://www.wikidata.org/entity/Q211164'), ('recordname', '2000 metres')]
# [('record', 'http://www.wikidata.org/entity/Q1135532'), ('recordname', 'World record progression 4 × 100 metres freestyle relay')]
# [('record', 'http://www.wikidata.org/entity/Q1053804'), ('recordname', "Men's 4 × 100 metres relay world record progression")]
# [('record', 'http://www.wikidata.org/entity/Q1187829'), ('recordname', "men's 200 metres world record progression")]
# [('record', 'http://www.wikidata.org/entity/Q1362958'), ('recordname', 'World record progression 200 metres freestyle')]
# [('record', 'http://www.wikidata.org/entity/Q3422175'), ('recordname', "Men's 200 metres European record progression")]
# 24

# %%
# aim: get all the records that could match the subclasses of 'long-distance running' through regexes having at least a 'record held' property connected
# result: all the records that could match the subclasses of 'long-distance running' through regexes having at least a 'record held' property connected
queryString = """
SELECT DISTINCT ?record ?recordname
WHERE {
   
   # ?record wdt:P1000 ?o .
   # get the label
   # ?record sc:name ?recordname.
   FILTER REGEX(?recordname,"marathon|10000|10,000|10K|5K|5000|one hour|one-hour|cross country|2 miles|20 kilometers|20,000|20000|15K|15,0000|Waffenlauf|2|1","i").
}
LIMIT 300
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('record', 'http://www.wikidata.org/entity/Q19980064'), ('recordname', 'Shindand An-12 crash')]
# [('record', 'http://www.wikidata.org/entity/Q240500'), ('recordname', '5000 metres')]
# [('record', 'http://www.wikidata.org/entity/Q40244'), ('recordname', 'marathon')]
# [('record', 'http://www.wikidata.org/entity/Q4581223'), ('recordname', '1983 TAAG Angola Airlines 737 Boeing crash')]
# [('record', 'http://www.wikidata.org/entity/Q3046072'), ('recordname', 'Air Algérie Flight 6289')]
# [('record', 'http://www.wikidata.org/entity/Q26172'), ('recordname', 'Junkers F-13')]
# [('record', 'http://www.wikidata.org/entity/Q19983192'), ('recordname', 'Air France D.342 crash')]
# [('record', 'http://www.wikidata.org/entity/Q949020'), ('recordname', 'USAir Flight 1493')]
# [('record', 'http://www.wikidata.org/entity/Q19993119'), ('recordname', 'Cuangar An-26 shootdown')]
# [('record', 'http://www.wikidata.org/entity/Q7184944'), ('recordname', 'Philippine Airlines Flight 143')]
# [('record', 'http://www.wikidata.org/entity/Q19909531'), ('recordname', 'Bagram Il-76 crash of 1979')]
# [('record', 'http://www.wikidata.org/entity/Q16868874'), ('recordname', '1958 C-130 shootdown')]
# 12

# %% [markdown]
# Final query for this task

# %%
# aim: get all the athletes who held a record for the disciplines 10000 metres, marathon, 5000 metres, one hour run and 5k run 
#      (probably 5k run is the same as 5000 metres run)
# result: all the athletes who held a record for the disciplines 10000 metres, marathon, 5000 metres, one hour run and 5k run 
#      (probably 5k run is the same as 5000 metres run). We couldn't find dates so we can't establish who is the one holding a record right now for
#      one of the given disciplines

queryString = """
SELECT DISTINCT ?discipline ?disciplinename ?athlete ?athletename
WHERE {
    {
        # athletes who held a record for the marathon world record progression
        SELECT DISTINCT (wd:Q40244 as ?discipline) ?disciplinename ?athlete ?athletename WHERE
        {
           wd:Q40244 sc:name ?disciplinename .
           # ?athlete wdt:P1000 wd:Q929585 .
           # get the label
           # ?athlete sc:name ?athletename.
        }
    }
    UNION
    {
        # get all the athletes associated to 'marathon' through 'record held'
        SELECT DISTINCT (wd:Q40244 as ?discipline) ?disciplinename ?athlete ?athletename WHERE
        {
           wd:Q40244 sc:name ?disciplinename ;
                wdt:P1000 ?athlete .
           # get the label
           # ?athlete sc:name ?athletename.
        }
    }
    UNION
    {
        # athletes who held a record for the 10000 metres 
        SELECT DISTINCT (wd:Q163892 as ?discipline) ?disciplinename ?athlete ?athletename WHERE
        {
           wd:Q163892 sc:name ?disciplinename .
           # ?athlete wdt:P1000 ?recordheld .
           # get the label
           # ?athlete sc:name ?athletename.
           FILTER(?recordheld IN (wd:Q52159822,wd:Q16714855,wd:Q163892))
        }
    
    }
    UNION
    {
        # athletes who held a record for the 5000 metres 
        SELECT DISTINCT (wd:Q240500 as ?discipline) ?disciplinename ?athlete ?athletename WHERE
        {
           wd:Q240500 sc:name ?disciplinename .
           # ?athlete wdt:P1000 wd:Q240500 .
           # get the label
           # ?athlete sc:name ?athletename.
        }
    
    }
    UNION
    {
        # athletes who held a record for the 5000 metres 
        SELECT DISTINCT (wd:Q240500 as ?discipline) ?disciplinename ?athlete ?athletename WHERE
        {
           wd:Q240500 sc:name ?disciplinename .
           wd:Q240500 wdt:P1000 ?athlete .
           # get the label
           # ?athlete sc:name ?athletename.
        }
    
    }
    UNION
    {
        # athletes who held a record for the 5K run
        SELECT DISTINCT (wd:Q9171043 as ?discipline) ?disciplinename ?athlete ?athletename WHERE
        {
           wd:Q9171043 sc:name ?disciplinename .
           # ?athlete wdt:P1000 wd:Q9171043 .
           # get the label
           # ?athlete sc:name ?athletename.
        }
    }
    UNION
    {
        # athletes who held a record for the one hour run
        SELECT DISTINCT (wd:Q2164200 as ?discipline) ?disciplinename ?athlete ?athletename WHERE
        {
           wd:Q2164200 sc:name ?disciplinename .
           # ?athlete wdt:P1000 wd:Q2164200 .
           # get the label
           # ?athlete sc:name ?athletename.
        }
    }
}
LIMIT 150
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('discipline', 'http://www.wikidata.org/entity/Q40244'), ('disciplinename', 'marathon'), ('athlete', 'http://www.wikidata.org/entity/Q1044585'), ('athletename', 'Caroline Walker')]
# [('discipline', 'http://www.wikidata.org/entity/Q40244'), ('disciplinename', 'marathon'), ('athlete', 'http://www.wikidata.org/entity/Q171500'), ('athletename', 'Gebrselassie Haile')]
# [('discipline', 'http://www.wikidata.org/entity/Q40244'), ('disciplinename', 'marathon'), ('athlete', 'http://www.wikidata.org/entity/Q728634'), ('athletename', 'Robert de Castella')]
# [('discipline', 'http://www.wikidata.org/entity/Q40244'), ('disciplinename', 'marathon'), ('athlete', 'http://www.wikidata.org/entity/Q9124'), ('athletename', 'Eliud Kipchoge')]
# [('discipline', 'http://www.wikidata.org/entity/Q40244'), ('disciplinename', 'marathon'), ('athlete', 'http://www.wikidata.org/entity/Q133667'), ('athletename', 'Sohn Kee-chung')]
# [('discipline', 'http://www.wikidata.org/entity/Q40244'), ('disciplinename', 'marathon'), ('athlete', 'http://www.wikidata.org/entity/Q7635174'), ('athletename', 'Suh Yun-bok')]
# [('discipline', 'http://www.wikidata.org/entity/Q40244'), ('disciplinename', 'marathon'), ('athlete', 'http://www.wikidata.org/entity/Q1705'), ('athletename', 'Wilson Kipsang Kiprotich')]
# [('discipline', 'http://www.wikidata.org/entity/Q40244'), ('disciplinename', 'marathon'), ('athlete', 'http://www.wikidata.org/entity/Q518358'), ('athletename', 'Beth Bonner')]
# [('discipline', 'http://www.wikidata.org/entity/Q40244'), ('disciplinename', 'marathon'), ('athlete', 'http://www.wikidata.org/entity/Q999436'), ('athletename', 'Morio Shigematsu')]
# [('discipline', 'http://www.wikidata.org/entity/Q40244'), ('disciplinename', 'marathon'), ('athlete', 'http://www.wikidata.org/entity/Q815310'), ('athletename', 'Belayneh Densamo')]
# [('discipline', 'http://www.wikidata.org/entity/Q40244'), ('disciplinename', 'marathon'), ('athlete', 'http://www.wikidata.org/entity/Q454958'), ('athletename', 'Carlos Lopes')]
# [('discipline', 'http://www.wikidata.org/entity/Q40244'), ('disciplinename', 'marathon'), ('athlete', 'http://www.wikidata.org/entity/Q456857'), ('athletename', 'Johnny Hayes')]
# [('discipline', 'http://www.wikidata.org/entity/Q40244'), ('disciplinename', 'marathon'), ('athlete', 'http://www.wikidata.org/entity/Q4710838'), ('athletename', 'Albert Michelsen')]
# [('discipline', 'http://www.wikidata.org/entity/Q40244'), ('disciplinename', 'marathon'), ('athlete', 'http://www.wikidata.org/entity/Q311338'), ('athletename', 'Hannes Kolehmainen')]
# [('discipline', 'http://www.wikidata.org/entity/Q40244'), ('disciplinename', 'marathon'), ('athlete', 'http://www.wikidata.org/entity/Q52596'), ('athletename', 'Abebe Bikila')]
# [('discipline', 'http://www.wikidata.org/entity/Q40244'), ('disciplinename', 'marathon'), ('athlete', 'http://www.wikidata.org/entity/Q63223'), ('athletename', 'Dennis Kipruto Kimetto')]
# [('discipline', 'http://www.wikidata.org/entity/Q40244'), ('disciplinename', 'marathon'), ('athlete', 'http://www.wikidata.org/entity/Q180891'), ('athletename', 'Sergei Popov')]
# [('discipline', 'http://www.wikidata.org/entity/Q40244'), ('disciplinename', 'marathon'), ('athlete', 'http://www.wikidata.org/entity/Q313799'), ('athletename', 'Paul Tergat')]
# [('discipline', 'http://www.wikidata.org/entity/Q40244'), ('disciplinename', 'marathon'), ('athlete', 'http://www.wikidata.org/entity/Q547285'), ('athletename', 'Anni Pede-Erdkamp')]
# [('discipline', 'http://www.wikidata.org/entity/Q40244'), ('disciplinename', 'marathon'), ('athlete', 'http://www.wikidata.org/entity/Q950340'), ('athletename', 'Ronaldo da Costa')]
# [('discipline', 'http://www.wikidata.org/entity/Q40244'), ('disciplinename', 'marathon'), ('athlete', 'http://www.wikidata.org/entity/Q428087'), ('athletename', 'Yasuo Ikenaka')]
# [('discipline', 'http://www.wikidata.org/entity/Q40244'), ('disciplinename', 'marathon'), ('athlete', 'http://www.wikidata.org/entity/Q443382'), ('athletename', 'Toru Terasawa')]
# [('discipline', 'http://www.wikidata.org/entity/Q40244'), ('disciplinename', 'marathon'), ('athlete', 'http://www.wikidata.org/entity/Q16210614'), ('athletename', 'Merry Lepper')]
# [('discipline', 'http://www.wikidata.org/entity/Q40244'), ('disciplinename', 'marathon'), ('athlete', 'http://www.wikidata.org/entity/Q5092701'), ('athletename', 'Cheryl Bridges')]
# [('discipline', 'http://www.wikidata.org/entity/Q40244'), ('disciplinename', 'marathon'), ('athlete', 'http://www.wikidata.org/entity/Q2605754'), ('athletename', 'Harry Green')]
# [('discipline', 'http://www.wikidata.org/entity/Q40244'), ('disciplinename', 'marathon'), ('athlete', 'http://www.wikidata.org/entity/Q1343502'), ('athletename', 'Khalid Khannouchi')]
# [('discipline', 'http://www.wikidata.org/entity/Q40244'), ('disciplinename', 'marathon'), ('athlete', 'http://www.wikidata.org/entity/Q7344468'), ('athletename', 'Robert Fowler')]
# [('discipline', 'http://www.wikidata.org/entity/Q40244'), ('disciplinename', 'marathon'), ('athlete', 'http://www.wikidata.org/entity/Q5543993'), ('athletename', 'Alexis Ahlgren')]
# [('discipline', 'http://www.wikidata.org/entity/Q40244'), ('disciplinename', 'marathon'), ('athlete', 'http://www.wikidata.org/entity/Q6131368'), ('athletename', 'James Clark')]
# [('discipline', 'http://www.wikidata.org/entity/Q40244'), ('disciplinename', 'marathon'), ('athlete', 'http://www.wikidata.org/entity/Q7799269'), ('athletename', 'Thure Johansson')]
# [('discipline', 'http://www.wikidata.org/entity/Q40244'), ('disciplinename', 'marathon'), ('athlete', 'http://www.wikidata.org/entity/Q7933273'), ('athletename', 'Violet Piercy')]
# [('discipline', 'http://www.wikidata.org/entity/Q40244'), ('disciplinename', 'marathon'), ('athlete', 'http://www.wikidata.org/entity/Q520969'), ('athletename', 'Miki Gorman')]
# [('discipline', 'http://www.wikidata.org/entity/Q40244'), ('disciplinename', 'marathon'), ('athlete', 'http://www.wikidata.org/entity/Q1001185'), ('athletename', 'Buddy Edelen')]
# [('discipline', 'http://www.wikidata.org/entity/Q40244'), ('disciplinename', 'marathon'), ('athlete', 'http://www.wikidata.org/entity/Q6851014'), ('athletename', 'Mildred Sampson')]
# [('discipline', 'http://www.wikidata.org/entity/Q40244'), ('disciplinename', 'marathon'), ('athlete', 'http://www.wikidata.org/entity/Q6792770'), ('athletename', 'Maureen Wilton')]
# [('discipline', 'http://www.wikidata.org/entity/Q40244'), ('disciplinename', 'marathon'), ('athlete', 'http://www.wikidata.org/entity/Q1200016'), ('athletename', 'Derek Clayton')]
# [('discipline', 'http://www.wikidata.org/entity/Q40244'), ('disciplinename', 'marathon'), ('athlete', 'http://www.wikidata.org/entity/Q5717831'), ('athletename', 'Henry Barrett')]
# [('discipline', 'http://www.wikidata.org/entity/Q40244'), ('disciplinename', 'marathon'), ('athlete', 'http://www.wikidata.org/entity/Q810031'), ('athletename', 'Basil Heatley')]
# [('discipline', 'http://www.wikidata.org/entity/Q40244'), ('disciplinename', 'marathon'), ('athlete', 'http://www.wikidata.org/entity/Q949816'), ('athletename', 'Jim Peters')]
# [('discipline', 'http://www.wikidata.org/entity/Q40244'), ('disciplinename', 'marathon'), ('athlete', 'http://www.wikidata.org/entity/Q334017'), ('athletename', 'Patrick Makau Musyoki')]
# [('discipline', 'http://www.wikidata.org/entity/Q40244'), ('disciplinename', 'marathon'), ('athlete', 'http://www.wikidata.org/entity/Q720491'), ('athletename', 'Steve Jones')]
# [('discipline', 'http://www.wikidata.org/entity/Q40244'), ('disciplinename', 'marathon'), ('athlete', 'http://www.wikidata.org/entity/Q5509922'), ('athletename', 'Fusashige Suzuki')]
# [('discipline', 'http://www.wikidata.org/entity/Q163892'), ('disciplinename', '10,000 metres'), ('athlete', 'http://www.wikidata.org/entity/Q9119'), ('athletename', 'Kenenisa Bekele Beyecha')]
# [('discipline', 'http://www.wikidata.org/entity/Q163892'), ('disciplinename', '10,000 metres'), ('athlete', 'http://www.wikidata.org/entity/Q5930934'), ('athletename', 'Jhon Cusi Huaman')]
# [('discipline', 'http://www.wikidata.org/entity/Q163892'), ('disciplinename', '10,000 metres'), ('athlete', 'http://www.wikidata.org/entity/Q9009157'), ('athletename', 'Inés Melchor')]
# [('discipline', 'http://www.wikidata.org/entity/Q240500'), ('disciplinename', '5000 metres'), ('athlete', 'http://www.wikidata.org/entity/Q9119'), ('athletename', 'Kenenisa Bekele Beyecha')]
# [('discipline', 'http://www.wikidata.org/entity/Q240500'), ('disciplinename', '5000 metres'), ('athlete', 'http://www.wikidata.org/entity/Q98780335'), ('athletename', 'Mike Foppen')]
# [('discipline', 'http://www.wikidata.org/entity/Q9171043'), ('disciplinename', '5K run'), ('athlete', 'http://www.wikidata.org/entity/Q9009157'), ('athletename', 'Inés Melchor')]
# [('discipline', 'http://www.wikidata.org/entity/Q2164200'), ('disciplinename', 'one hour run'), ('athlete', 'http://www.wikidata.org/entity/Q171500'), ('athletename', 'Gebrselassie Haile')]
# 49

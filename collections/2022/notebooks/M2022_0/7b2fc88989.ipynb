# %% [markdown]
# # General instructions
#
# The goal of the project is to materialize a set of **exploratory workloads** over a real-world, large-scale,  open-domain KG: [WikiData](https://www.wikidata.org/wiki/Wikidata:Main_Page)
#
# An exploratory workload  is composed by a set of queries, where each query is related to the information obtained previously.
#
# An exploratory workload starts with a usually vague, open ended question, and does not assume the person issuing the workload has a clear understanding of the data contained in the target database or its structure.
#
# Remeber that:
#
# 1. All the queries must run in the python notebook
# 2. You can use classes and properties only if you find them via a SPARQL query that must be present in the notebook
# 3. You do not delete useless queries. Keep everything that is synthatically valid
#
# ```
# ?p <http://schema.org/name> ?name .
# ```
#
#     is the BGP returning a human-readable name of a property or a class in Wikidata.

# %%
## SETUP used later

from SPARQLWrapper import SPARQLWrapper, JSON


prefixString = """
##-7b2fc88989-##
PREFIX wd: <http://www.wikidata.org/entity/> 
PREFIX wdt: <http://www.wikidata.org/prop/direct/> 
PREFIX sc: <http://schema.org/>
"""

# select and construct queries
def run_query(queryString,verbose = True):
    to_run = prefixString + "\n" + queryString

    sparql = SPARQLWrapper("http://a256-gc1-03.srv.aau.dk:5820/sparql")
    sparql.setTimeout(300)
    sparql.setReturnFormat(JSON)
    sparql.setQuery(to_run)

    try :
        results = sparql.query()
        json_results = results.convert()
        if len(json_results['results']['bindings'])==0:
            print("Empty")
            return []
        array = []
        for bindings in json_results['results']['bindings']:
            app =  [ (var, value['value'])  for var, value in bindings.items() ] 
            if verbose:
                print( app)
            array.append(app)
        if verbose:
            print(len(array))
        return array

    except Exception as e :
        print("The operation failed", e)
    
# ASk queries
def run_ask_query(queryString):
    to_run = prefixString + "\n" + queryString

    sparql = SPARQLWrapper("http://a256-gc1-03.srv.aau.dk:5820/sparql")
    sparql.setTimeout(300)
    sparql.setReturnFormat(JSON)
    sparql.setQuery(to_run)

    try :
        return sparql.query().convert()

    except Exception as e :
        print("The operation failed", e)

# %% [markdown]
# # Movie Workflow Series ("Production company explorative search")
#
# Consider the following exploratory information need:
#
# > investigate the main companies working on cinema-related content. We want to know which are the main television production companies and the film production companies, which company distributes more film and some consideration about awards.

# %% [markdown]
# ## Useful URIs for the current workflow
# The following are given:
#
# | IRI           | Description   | Role      |
# | -----------   | -----------   |-----------|
# | `wdt:P1647`   | subproperty   | predicate |
# | `wdt:P31`     | instance of   | predicate |
# | `wdt:P106`    | profession    | predicate |
# | `wdt:P279`    | subclass      | predicate |
# | `wdt:P27`     | nationality   | predicate |
# | `wdt:P106`     | profession   | predicate |
# | `wd:Q5`| Human       | node |
# | `wd:Q36479`    | The Lion King      | node |

# %% [markdown]
# Also consider
#
# ```
# wd:Q36479 ?p ?obj .
# ```
#
# is the BGP to retrieve all **properties of The Lion King**
#
# Please consider that when you return a resource, you should return the IRI and the label of the resource. In particular, when the task require you to identify a BGP the result set must always be a list of couples IRI - label.
#
# The workload should:
#
#
# 1. Identify the BGP for films
#
# 2. Identify the BGP for Netflix
#
# 3. Identify the BGP for television production company
#
# 4. Identify the BGP for film production company
#
# 5. Find the top-5 companies (amongst television production company and film production company) which produced the highest number of crime films (the result set must be a list of triples company IRI, label and #crime film).
#
# 6. Find the company (amongst television production company and film production company) which distributed more films (of any kind of film genre) that they did not produce (the result set must be a list of triples company IRI, label and #film).
#
# 7. Find how many company are listed in every stock exchange market (the result set must be a list of triples stock exchange IRI, label and #companies).
#
# 8. Identify the BGP for Academy Award
#
# 9. Find the companies (among television and film production companies) that won at least 5 Academy Awards for Best Actress for the movies they produced (the result set must be a list of triples company IRI, label and #awards).

# %% [markdown]
# ## Task 1
# Identify the BGP for films

# %%
#all the properties for The lion King. 
queryString = """
SELECT DISTINCT ?p ?name
WHERE {
   # bind something
   wd:Q36479 ?p ?obj .
   # get the label
   # ?p sc:name ?name.
}
ORDER BY ?iname
LIMIT 500
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P3092'), ('name', 'film crew member')]
# [('p', 'http://www.wikidata.org/prop/direct/P4021'), ('name', 'danskefilm animated film ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7679'), ('name', 'Cinépolis KLIC ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1015'), ('name', 'NORAF ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1040'), ('name', 'film editor')]
# [('p', 'http://www.wikidata.org/prop/direct/P1237'), ('name', 'Box Office Mojo film ID (former scheme)')]
# [('p', 'http://www.wikidata.org/prop/direct/P1258'), ('name', 'Rotten Tomatoes ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1265'), ('name', 'AlloCiné film ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1273'), ('name', 'CANTIC ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P136'), ('name', 'genre')]
# [('p', 'http://www.wikidata.org/prop/direct/P1411'), ('name', 'nominated for')]
# [('p', 'http://www.wikidata.org/prop/direct/P1417'), ('name', 'Encyclopædia Britannica Online ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1434'), ('name', 'takes place in fictional universe')]
# [('p', 'http://www.wikidata.org/prop/direct/P144'), ('name', 'based on')]
# [('p', 'http://www.wikidata.org/prop/direct/P1476'), ('name', 'title')]
# [('p', 'http://www.wikidata.org/prop/direct/P154'), ('name', 'logo image')]
# [('p', 'http://www.wikidata.org/prop/direct/P1552'), ('name', 'has quality')]
# [('p', 'http://www.wikidata.org/prop/direct/P156'), ('name', 'followed by')]
# [('p', 'http://www.wikidata.org/prop/direct/P1562'), ('name', 'AllMovie title ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P162'), ('name', 'producer')]
# [('p', 'http://www.wikidata.org/prop/direct/P1657'), ('name', 'MPAA film rating')]
# [('p', 'http://www.wikidata.org/prop/direct/P166'), ('name', 'award received')]
# [('p', 'http://www.wikidata.org/prop/direct/P1712'), ('name', 'Metacritic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P175'), ('name', 'performer')]
# [('p', 'http://www.wikidata.org/prop/direct/P179'), ('name', 'part of the series')]
# [('p', 'http://www.wikidata.org/prop/direct/P1804'), ('name', 'DNF film ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1874'), ('name', 'Netflix ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1889'), ('name', 'different from')]
# [('p', 'http://www.wikidata.org/prop/direct/P1970'), ('name', 'MovieMeter film ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2047'), ('name', 'duration')]
# [('p', 'http://www.wikidata.org/prop/direct/P2079'), ('name', 'fabrication method')]
# [('p', 'http://www.wikidata.org/prop/direct/P2130'), ('name', 'cost')]
# [('p', 'http://www.wikidata.org/prop/direct/P214'), ('name', 'VIAF ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2142'), ('name', 'box office')]
# [('p', 'http://www.wikidata.org/prop/direct/P227'), ('name', 'GND ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2334'), ('name', 'Swedish Film Database film ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2346'), ('name', 'Elonet movie ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2364'), ('name', 'production code')]
# [('p', 'http://www.wikidata.org/prop/direct/P244'), ('name', 'Library of Congress authority ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2465'), ('name', 'Allcinema film ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2508'), ('name', 'KINENOTE film ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2518'), ('name', 'Scope.dk film ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2529'), ('name', 'ČSFD film ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2603'), ('name', 'Kinopoisk film ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2631'), ('name', 'TCM Movie Database film ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2638'), ('name', 'TV.com ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P268'), ('name', 'Bibliothèque nationale de France ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2704'), ('name', 'EIDR content ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P272'), ('name', 'production company')]
# [('p', 'http://www.wikidata.org/prop/direct/P2747'), ('name', 'Filmiroda rating')]
# [('p', 'http://www.wikidata.org/prop/direct/P2755'), ('name', 'exploitation visa number')]
# [('p', 'http://www.wikidata.org/prop/direct/P2758'), ('name', 'CNC film rating (France)')]
# [('p', 'http://www.wikidata.org/prop/direct/P2769'), ('name', 'budget')]
# [('p', 'http://www.wikidata.org/prop/direct/P3077'), ('name', 'Cineplex Germany film ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('name', 'instance of')]
# [('p', 'http://www.wikidata.org/prop/direct/P3107'), ('name', 'LdiF ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3110'), ('name', 'ISzDb film ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3138'), ('name', 'OFDb film ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3203'), ('name', 'Ciné-Ressources film ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3212'), ('name', 'ISAN')]
# [('p', 'http://www.wikidata.org/prop/direct/P3280'), ('name', 'BAnQ author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3302'), ('name', 'Open Media Database film ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3402'), ('name', 'CNC film rating (Romania)')]
# [('p', 'http://www.wikidata.org/prop/direct/P3417'), ('name', 'Quora topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P345'), ('name', 'IMDb ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3509'), ('name', 'Dagens Nyheter topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3553'), ('name', 'Zhihu topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3593'), ('name', 'AFI Catalog of Feature Films ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P364'), ('name', 'original language of film or TV show')]
# [('p', 'http://www.wikidata.org/prop/direct/P373'), ('name', 'Commons category')]
# [('p', 'http://www.wikidata.org/prop/direct/P3804'), ('name', 'TV Guide show ID (former scheme)')]
# [('p', 'http://www.wikidata.org/prop/direct/P3808'), ('name', 'The Numbers movie ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3834'), ('name', 'RTC film rating')]
# [('p', 'http://www.wikidata.org/prop/direct/P3844'), ('name', 'Deutsche Synchronkartei film ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P4276'), ('name', 'Cinémathèque québécoise work identifier')]
# [('p', 'http://www.wikidata.org/prop/direct/P4282'), ('name', 'LUMIERE film ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P437'), ('name', 'distribution format')]
# [('p', 'http://www.wikidata.org/prop/direct/P4515'), ('name', 'Prisma ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P4529'), ('name', 'Douban film ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P4619'), ('name', 'National Library of Brazil ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P462'), ('name', 'color')]
# [('p', 'http://www.wikidata.org/prop/direct/P4632'), ('name', 'Bechdel Test Movie List ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P4665'), ('name', 'CineMagia title ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P4786'), ('name', 'cinematografo film ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P480'), ('name', 'FilmAffinity ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P4947'), ('name', 'TMDb movie ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P495'), ('name', 'country of origin')]
# [('p', 'http://www.wikidata.org/prop/direct/P4969'), ('name', 'derivative work')]
# [('p', 'http://www.wikidata.org/prop/direct/P5021'), ('name', 'assessment')]
# [('p', 'http://www.wikidata.org/prop/direct/P5099'), ('name', 'Il mondo dei doppiatori ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P57'), ('name', 'director')]
# [('p', 'http://www.wikidata.org/prop/direct/P577'), ('name', 'publication date')]
# [('p', 'http://www.wikidata.org/prop/direct/P5786'), ('name', 'Moviepilot.de film ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P58'), ('name', 'screenwriter')]
# [('p', 'http://www.wikidata.org/prop/direct/P5885'), ('name', 'Microsoft Store product ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5905'), ('name', 'Comic Vine ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6127'), ('name', 'Letterboxd film ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6145'), ('name', 'Academy Awards Database film ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6181'), ('name', 'Disney A to Z ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6262'), ('name', 'Fandom article ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6398'), ('name', 'iTunes movie ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P646'), ('name', 'Freebase ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6562'), ('name', 'Google Play Movies & TV ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P674'), ('name', 'characters')]
# [('p', 'http://www.wikidata.org/prop/direct/P6839'), ('name', 'TV Tropes identifier')]
# [('p', 'http://www.wikidata.org/prop/direct/P6900'), ('name', 'NicoNicoPedia ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7212'), ('name', 'LyricsTranslate ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7293'), ('name', 'PLWABN ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7299'), ('name', 'MUBI film ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P747'), ('name', 'has edition or translation')]
# [('p', 'http://www.wikidata.org/prop/direct/P750'), ('name', 'distributed by')]
# [('p', 'http://www.wikidata.org/prop/direct/P7818'), ('name', 'French Vikidia ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P793'), ('name', 'significant event')]
# [('p', 'http://www.wikidata.org/prop/direct/P8033'), ('name', 'Movie Review Query Engine ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8345'), ('name', 'media franchise')]
# [('p', 'http://www.wikidata.org/prop/direct/P840'), ('name', 'narrative location')]
# [('p', 'http://www.wikidata.org/prop/direct/P8411'), ('name', 'set in environment')]
# [('p', 'http://www.wikidata.org/prop/direct/P856'), ('name', 'official website')]
# [('p', 'http://www.wikidata.org/prop/direct/P86'), ('name', 'composer')]
# [('p', 'http://www.wikidata.org/prop/direct/P8847'), ('name', 'Kinorium movie ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P905'), ('name', 'PORT film ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P910'), ('name', "topic's main category")]
# [('p', 'http://www.wikidata.org/prop/direct/P941'), ('name', 'inspired by')]
# [('p', 'http://www.wikidata.org/prop/direct/P950'), ('name', 'Biblioteca Nacional de España ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P9586'), ('name', 'Apple TV movie ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2554'), ('name', 'production designer')]
# [('p', 'http://www.wikidata.org/prop/direct/P1431'), ('name', 'executive producer')]
# [('p', 'http://www.wikidata.org/prop/direct/P3854'), ('name', 'Soundtrack Collector ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P406'), ('name', 'soundtrack release')]
# [('p', 'http://www.wikidata.org/prop/direct/P4933'), ('name', 'Big Cartoon Database ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5311'), ('name', 'Kino-teatr.ua film ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5384'), ('name', 'Behind The Voice Actors film ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7595'), ('name', 'Disney+ movie ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7975'), ('name', 'Filmfront film ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P942'), ('name', 'theme music')]
# [('p', 'http://www.wikidata.org/prop/direct/P3174'), ('name', 'art director')]
# [('p', 'http://www.wikidata.org/prop/direct/P7118'), ('name', 'AMPAS collections film ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P725'), ('name', 'voice actor')]
# [('p', 'http://www.wikidata.org/prop/direct/P3275'), ('name', 'storyboard artist')]
# [('p', 'http://www.wikidata.org/prop/direct/P4483'), ('name', 'INDUCKS story ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6942'), ('name', 'animator')]
# 141

# %%
queryString = """
SELECT DISTINCT ?inst ?iname 
WHERE {
   # bind something
   wd:Q36479 ?p ?obj .
   # ?obj wdt:P31 ?inst.
   
   # get the label
   # ?inst sc:name ?iname.
}
ORDER BY ?iname
LIMIT 200
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('inst', 'http://www.wikidata.org/entity/Q19020'), ('iname', 'Academy Awards')]
# [('inst', 'http://www.wikidata.org/entity/Q23817731'), ('iname', 'CNC film classification category')]
# [('inst', 'http://www.wikidata.org/entity/Q27915572'), ('iname', 'CNC film classification category')]
# [('inst', 'http://www.wikidata.org/entity/Q23830575'), ('iname', 'Filmiroda rating category')]
# [('inst', 'http://www.wikidata.org/entity/Q841645'), ('iname', 'Internet television')]
# [('inst', 'http://www.wikidata.org/entity/Q23660208'), ('iname', 'MPAA classification category')]
# [('inst', 'http://www.wikidata.org/entity/Q28980086'), ('iname', 'RTC film classification category')]
# [('inst', 'http://www.wikidata.org/entity/Q15708861'), ('iname', 'Red-billed Hornbill')]
# [('inst', 'http://www.wikidata.org/entity/Q4167836'), ('iname', 'Wikimedia category')]
# [('inst', 'http://www.wikidata.org/entity/Q482994'), ('iname', 'album')]
# [('inst', 'http://www.wikidata.org/entity/Q15711870'), ('iname', 'animated character')]
# [('inst', 'http://www.wikidata.org/entity/Q29168811'), ('iname', 'animated feature film')]
# [('inst', 'http://www.wikidata.org/entity/Q56884562'), ('iname', 'animated film series')]
# [('inst', 'http://www.wikidata.org/entity/Q1107679'), ('iname', 'animation studio')]
# [('inst', 'http://www.wikidata.org/entity/Q3516833'), ('iname', 'animation technique')]
# [('inst', 'http://www.wikidata.org/entity/Q27921916'), ('iname', 'anthropomorphic character')]
# [('inst', 'http://www.wikidata.org/entity/Q88594442'), ('iname', 'anthropomorphic lion')]
# [('inst', 'http://www.wikidata.org/entity/Q99768828'), ('iname', 'anthropomorphic meerkat')]
# [('inst', 'http://www.wikidata.org/entity/Q88553702'), ('iname', 'anthropomorphic monkey')]
# [('inst', 'http://www.wikidata.org/entity/Q99972219'), ('iname', 'anthropomorphic suid')]
# [('inst', 'http://www.wikidata.org/entity/Q3814081'), ('iname', 'app store')]
# [('inst', 'http://www.wikidata.org/entity/Q96474685'), ('iname', 'award for best original music')]
# [('inst', 'http://www.wikidata.org/entity/Q29154430'), ('iname', 'book of the Bible')]
# [('inst', 'http://www.wikidata.org/entity/Q15265344'), ('iname', 'broadcaster')]
# [('inst', 'http://www.wikidata.org/entity/Q4830453'), ('iname', 'business')]
# [('inst', 'http://www.wikidata.org/entity/Q1001378'), ('iname', 'cinematic technique')]
# [('inst', 'http://www.wikidata.org/entity/Q1075'), ('iname', 'color')]
# [('inst', 'http://www.wikidata.org/entity/Q859170'), ('iname', 'color scheme')]
# [('inst', 'http://www.wikidata.org/entity/Q28968258'), ('iname', 'computer-animated film')]
# [('inst', 'http://www.wikidata.org/entity/Q1520223'), ('iname', 'constitutional republic')]
# [('inst', 'http://www.wikidata.org/entity/Q5107'), ('iname', 'continent')]
# [('inst', 'http://www.wikidata.org/entity/Q6256'), ('iname', 'country')]
# [('inst', 'http://www.wikidata.org/entity/Q861437'), ('iname', 'cultural canon')]
# [('inst', 'http://www.wikidata.org/entity/Q5255892'), ('iname', 'democratic republic')]
# [('inst', 'http://www.wikidata.org/entity/Q269415'), ('iname', 'digital distribution')]
# [('inst', 'http://www.wikidata.org/entity/Q1194970'), ('iname', 'dot-com company')]
# [('inst', 'http://www.wikidata.org/entity/Q58483083'), ('iname', 'dramatico-musical work')]
# [('inst', 'http://www.wikidata.org/entity/Q26204053'), ('iname', 'dubbing of film')]
# [('inst', 'http://www.wikidata.org/entity/Q512187'), ('iname', 'federal republic')]
# [('inst', 'http://www.wikidata.org/entity/Q15832079'), ('iname', 'fictional bird')]
# [('inst', 'http://www.wikidata.org/entity/Q95074'), ('iname', 'fictional character')]
# [('inst', 'http://www.wikidata.org/entity/Q24577840'), ('iname', 'fictional group of characters')]
# [('inst', 'http://www.wikidata.org/entity/Q27267085'), ('iname', 'fictional lion')]
# [('inst', 'http://www.wikidata.org/entity/Q88553705'), ('iname', 'fictional mandrill')]
# [('inst', 'http://www.wikidata.org/entity/Q559618'), ('iname', 'fictional universe')]
# [('inst', 'http://www.wikidata.org/entity/Q368290'), ('iname', 'film distributor')]
# [('inst', 'http://www.wikidata.org/entity/Q201658'), ('iname', 'film genre')]
# [('inst', 'http://www.wikidata.org/entity/Q1762059'), ('iname', 'film production company')]
# [('inst', 'http://www.wikidata.org/entity/Q99541706'), ('iname', 'historical unrecognized state')]
# [('inst', 'http://www.wikidata.org/entity/Q5'), ('iname', 'human')]
# [('inst', 'http://www.wikidata.org/entity/Q34770'), ('iname', 'language')]
# [('inst', 'http://www.wikidata.org/entity/Q7725634'), ('iname', 'literary work')]
# [('inst', 'http://www.wikidata.org/entity/Q196600'), ('iname', 'media franchise')]
# [('inst', 'http://www.wikidata.org/entity/Q1288568'), ('iname', 'modern language')]
# [('inst', 'http://www.wikidata.org/entity/Q105543609'), ('iname', 'musical work/composition')]
# [('inst', 'http://www.wikidata.org/entity/Q46169'), ('iname', 'national park')]
# [('inst', 'http://www.wikidata.org/entity/Q33742'), ('iname', 'natural language')]
# [('inst', 'http://www.wikidata.org/entity/Q25379'), ('iname', 'play')]
# [('inst', 'http://www.wikidata.org/entity/Q81941037'), ('iname', 'product distribution method')]
# [('inst', 'http://www.wikidata.org/entity/Q170584'), ('iname', 'project')]
# [('inst', 'http://www.wikidata.org/entity/Q891723'), ('iname', 'public company')]
# [('inst', 'http://www.wikidata.org/entity/Q179461'), ('iname', 'religious text')]
# [('inst', 'http://www.wikidata.org/entity/Q102179937'), ('iname', 'representation test')]
# [('inst', 'http://www.wikidata.org/entity/Q1668024'), ('iname', 'service on internet')]
# [('inst', 'http://www.wikidata.org/entity/Q134556'), ('iname', 'single')]
# [('inst', 'http://www.wikidata.org/entity/Q3624078'), ('iname', 'sovereign state')]
# [('inst', 'http://www.wikidata.org/entity/Q1489259'), ('iname', 'superpower')]
# [('inst', 'http://www.wikidata.org/entity/Q10689397'), ('iname', 'television production company')]
# [('inst', 'http://www.wikidata.org/entity/Q3375722'), ('iname', 'theatrical character')]
# [('inst', 'http://www.wikidata.org/entity/Q2083910'), ('iname', 'vegetation zone')]
# [('inst', 'http://www.wikidata.org/entity/Q723685'), ('iname', 'video on demand')]
# [('inst', 'http://www.wikidata.org/entity/Q59152282'), ('iname', 'video streaming service')]
# 72

# %%
#I explore the properties for animated feature film 
queryString = """
SELECT DISTINCT ?p ?name
WHERE {
   # bind something
   wd:Q29168811 ?p ?obj .
   # get the label
   # ?p sc:name ?name.
}
LIMIT 500
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('name', 'subclass of')]
# [('p', 'http://www.wikidata.org/prop/direct/P461'), ('name', 'opposite of')]
# [('p', 'http://www.wikidata.org/prop/direct/P8408'), ('name', 'KBpedia ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P910'), ('name', "topic's main category")]
# 4

# %%
#Lets see from who its subclass of. 
queryString = """
SELECT DISTINCT ?inst ?iname 
WHERE {
   # bind something
   wd:Q29168811 ?p ?obj .
   # ?obj wdt:P279 ?inst.
   
   # get the label
   # ?inst sc:name ?iname.
}
ORDER BY ?iname
LIMIT 200
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('inst', 'http://www.wikidata.org/entity/Q202866'), ('iname', 'animated film')]
# [('inst', 'http://www.wikidata.org/entity/Q11424'), ('iname', 'film')]
# [('inst', 'http://www.wikidata.org/entity/Q24862'), ('iname', 'short film')]
# 3

# %% [markdown]
# Final query for this task

# %%
#Found with the last query, the BGP for film. Finding out from who its subclass the animated feature film. 
queryString = """
SELECT DISTINCT ?inst ?iname 
WHERE {
   # bind something
   wd:Q29168811 ?p ?obj .
   # ?obj wdt:P279 ?inst.
   
   # get the label
   # ?inst sc:name ?iname.
}
ORDER BY ?iname
LIMIT 200
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('inst', 'http://www.wikidata.org/entity/Q202866'), ('iname', 'animated film')]
# [('inst', 'http://www.wikidata.org/entity/Q11424'), ('iname', 'film')]
# [('inst', 'http://www.wikidata.org/entity/Q24862'), ('iname', 'short film')]
# 3

# %% [markdown]
# ## Task 2
# Identify the BGP for Netflix

# %%
#Netflix it's a distribution company so lets look for the BGP of distributor and then all the companies 
#Lets start looking for the property of the lion king called netflix ID. see what contains P1874
queryString = """
SELECT DISTINCT ?inst ?iname 
WHERE {
   # bind something
   wd:Q36479 ?p ?obj .
   # ?obj wdt:P1874 ?inst.
   
   # get the label
   # ?inst sc:name ?iname.
}
ORDER BY ?iname
LIMIT 200
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# Empty

# %% [markdown]
# Final query for this task

# %%
#Keep looking for properties. Explore the property distribuited by. P750
queryString = """
SELECT DISTINCT ?inst ?iname 
WHERE {
   # bind something
   wd:Q36479 ?p ?obj .
   # ?obj wdt:P750 ?inst.
   
   # get the label
   # ?inst sc:name ?iname.
}
ORDER BY ?iname
LIMIT 200
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('inst', 'http://www.wikidata.org/entity/Q54958752'), ('iname', 'Disney+')]
# [('inst', 'http://www.wikidata.org/entity/Q1097348'), ('iname', 'InterCom')]
# [('inst', 'http://www.wikidata.org/entity/Q135288'), ('iname', 'Microsoft Store')]
# [('inst', 'http://www.wikidata.org/entity/Q907311'), ('iname', 'Netflix')]
# [('inst', 'http://www.wikidata.org/entity/Q1323594'), ('iname', 'Walt Disney Studios Motion Pictures')]
# 5

# %% [markdown]
# ## Task 3
# Identify the BGP for television production company

# %%
#let's see the properties from Netflix
queryString = """
SELECT DISTINCT ?p ?name
WHERE {
   # bind something
   wd:Q907311 ?p ?obj .
   # get the label
   # ?p sc:name ?name.
}
ORDER BY ?iname
LIMIT 500
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P8939'), ('name', 'Google Play developer slug')]
# [('p', 'http://www.wikidata.org/prop/direct/P1056'), ('name', 'product or material produced')]
# [('p', 'http://www.wikidata.org/prop/direct/P112'), ('name', 'founded by')]
# [('p', 'http://www.wikidata.org/prop/direct/P1128'), ('name', 'employees')]
# [('p', 'http://www.wikidata.org/prop/direct/P127'), ('name', 'owned by')]
# [('p', 'http://www.wikidata.org/prop/direct/P1411'), ('name', 'nominated for')]
# [('p', 'http://www.wikidata.org/prop/direct/P1417'), ('name', 'Encyclopædia Britannica Online ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1424'), ('name', "topic's main template")]
# [('p', 'http://www.wikidata.org/prop/direct/P1454'), ('name', 'legal form')]
# [('p', 'http://www.wikidata.org/prop/direct/P154'), ('name', 'logo image')]
# [('p', 'http://www.wikidata.org/prop/direct/P1581'), ('name', 'official blog')]
# [('p', 'http://www.wikidata.org/prop/direct/P159'), ('name', 'headquarters location')]
# [('p', 'http://www.wikidata.org/prop/direct/P166'), ('name', 'award received')]
# [('p', 'http://www.wikidata.org/prop/direct/P1661'), ('name', 'Alexa rank')]
# [('p', 'http://www.wikidata.org/prop/direct/P1687'), ('name', 'Wikidata property')]
# [('p', 'http://www.wikidata.org/prop/direct/P169'), ('name', 'chief executive officer')]
# [('p', 'http://www.wikidata.org/prop/direct/P17'), ('name', 'country')]
# [('p', 'http://www.wikidata.org/prop/direct/P18'), ('name', 'image')]
# [('p', 'http://www.wikidata.org/prop/direct/P1833'), ('name', 'number of registered users/contributors')]
# [('p', 'http://www.wikidata.org/prop/direct/P1846'), ('name', 'distribution map')]
# [('p', 'http://www.wikidata.org/prop/direct/P2002'), ('name', 'Twitter username')]
# [('p', 'http://www.wikidata.org/prop/direct/P2003'), ('name', 'Instagram username')]
# [('p', 'http://www.wikidata.org/prop/direct/P2013'), ('name', 'Facebook ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2037'), ('name', 'GitHub username')]
# [('p', 'http://www.wikidata.org/prop/direct/P2088'), ('name', 'Crunchbase organization ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2139'), ('name', 'total revenue')]
# [('p', 'http://www.wikidata.org/prop/direct/P214'), ('name', 'VIAF ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P227'), ('name', 'GND ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2283'), ('name', 'uses')]
# [('p', 'http://www.wikidata.org/prop/direct/P2295'), ('name', 'net profit')]
# [('p', 'http://www.wikidata.org/prop/direct/P2397'), ('name', 'YouTube channel ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2403'), ('name', 'total assets')]
# [('p', 'http://www.wikidata.org/prop/direct/P2427'), ('name', 'GRID ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P244'), ('name', 'Library of Congress authority ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2572'), ('name', 'hashtag')]
# [('p', 'http://www.wikidata.org/prop/direct/P268'), ('name', 'Bibliothèque nationale de France ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('name', 'instance of')]
# [('p', 'http://www.wikidata.org/prop/direct/P3106'), ('name', 'Guardian topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3222'), ('name', 'NE.se ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3362'), ('name', 'operating income')]
# [('p', 'http://www.wikidata.org/prop/direct/P3417'), ('name', 'Quora topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3418'), ('name', 'Google Play Store app ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P355'), ('name', 'subsidiary')]
# [('p', 'http://www.wikidata.org/prop/direct/P3553'), ('name', 'Zhihu topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P361'), ('name', 'part of')]
# [('p', 'http://www.wikidata.org/prop/direct/P373'), ('name', 'Commons category')]
# [('p', 'http://www.wikidata.org/prop/direct/P3797'), ('name', 'autonomous system number')]
# [('p', 'http://www.wikidata.org/prop/direct/P3836'), ('name', 'Pinterest username')]
# [('p', 'http://www.wikidata.org/prop/direct/P3861'), ('name', 'App Store app ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3984'), ('name', 'subreddit')]
# [('p', 'http://www.wikidata.org/prop/direct/P400'), ('name', 'platform')]
# [('p', 'http://www.wikidata.org/prop/direct/P4013'), ('name', 'Giphy username')]
# [('p', 'http://www.wikidata.org/prop/direct/P407'), ('name', 'language of work or name')]
# [('p', 'http://www.wikidata.org/prop/direct/P4073'), ('name', 'Fandom wiki ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P414'), ('name', 'stock exchange')]
# [('p', 'http://www.wikidata.org/prop/direct/P4264'), ('name', 'LinkedIn company ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P4342'), ('name', 'Store norske leksikon ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P4354'), ('name', 'search formatter URL')]
# [('p', 'http://www.wikidata.org/prop/direct/P452'), ('name', 'industry')]
# [('p', 'http://www.wikidata.org/prop/direct/P4527'), ('name', 'UK Parliament thesaurus ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P463'), ('name', 'member of')]
# [('p', 'http://www.wikidata.org/prop/direct/P4776'), ('name', 'MAC Address Block Large ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5019'), ('name', 'Brockhaus Enzyklopädie online ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P571'), ('name', 'inception')]
# [('p', 'http://www.wikidata.org/prop/direct/P6181'), ('name', 'Disney A to Z ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6262'), ('name', 'Fandom article ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6366'), ('name', 'Microsoft Academic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P646'), ('name', 'Freebase ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6760'), ('name', 'Know Your Meme ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6782'), ('name', 'ROR ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6839'), ('name', 'TV Tropes identifier')]
# [('p', 'http://www.wikidata.org/prop/direct/P6849'), ('name', 'DR topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6900'), ('name', 'NicoNicoPedia ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P691'), ('name', 'NKCR AUT ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7085'), ('name', 'TikTok username')]
# [('p', 'http://www.wikidata.org/prop/direct/P7157'), ('name', 'The Top Tens ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7306'), ('name', 'Downdetector ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P740'), ('name', 'location of formation')]
# [('p', 'http://www.wikidata.org/prop/direct/P7502'), ('name', 'Golden ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7771'), ('name', 'PersonalData.IO ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7818'), ('name', 'French Vikidia ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7859'), ('name', 'WorldCat Identities ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P856'), ('name', 'official website')]
# [('p', 'http://www.wikidata.org/prop/direct/P8687'), ('name', 'social media followers')]
# [('p', 'http://www.wikidata.org/prop/direct/P910'), ('name', "topic's main category")]
# [('p', 'http://www.wikidata.org/prop/direct/P9100'), ('name', 'GitHub topic')]
# [('p', 'http://www.wikidata.org/prop/direct/P9138'), ('name', 'service status information URL')]
# [('p', 'http://www.wikidata.org/prop/direct/P9346'), ('name', 'France24 topic ID (French)')]
# [('p', 'http://www.wikidata.org/prop/direct/P946'), ('name', 'ISIN')]
# [('p', 'http://www.wikidata.org/prop/direct/P9618'), ('name', 'AlternativeTo software ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P966'), ('name', 'MusicBrainz label ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P973'), ('name', 'described at URL')]
# [('p', 'http://www.wikidata.org/prop/direct/P3242'), ('name', 'SIC code')]
# [('p', 'http://www.wikidata.org/prop/direct/P5531'), ('name', 'Central Index Key')]
# [('p', 'http://www.wikidata.org/prop/direct/P6869'), ('name', 'Hoopla publisher ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7997'), ('name', 'GRY-Online company ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2531'), ('name', 'Box Office Mojo studio ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5576'), ('name', 'EDb company ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6954'), ('name', 'online access status')]
# 99

# %%
#From who it's instance of Netflix. 
queryString = """
SELECT DISTINCT ?inst ?iname 
WHERE {
   # bind something
   wd:Q907311 ?p ?obj .
   # ?obj wdt:P31 ?inst.
   
   # get the label
   # ?inst sc:name ?iname.
}
ORDER BY ?iname
LIMIT 200
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# Empty

# %%
#I go for another path and look on the properties of The lion king, I take a look to the values on the properti production company.
queryString = """
SELECT DISTINCT ?inst ?iname 
WHERE {
   # bind something
   wd:Q36479 ?p ?obj .
   # ?obj wdt:P272 ?inst.
   
   # get the label
   # ?inst sc:name ?iname.
}
ORDER BY ?iname
LIMIT 200
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('inst', 'http://www.wikidata.org/entity/Q2081339'), ('iname', 'Disneytoon Studios')]
# [('inst', 'http://www.wikidata.org/entity/Q3866664'), ('iname', 'Moving Picture Company')]
# [('inst', 'http://www.wikidata.org/entity/Q7414'), ('iname', 'The Walt Disney Company')]
# [('inst', 'http://www.wikidata.org/entity/Q191224'), ('iname', 'Walt Disney Pictures')]
# 4

# %%
#Now I explore walt disney Pictures
queryString = """
SELECT DISTINCT ?p ?name
WHERE {
   # bind something
   wd:Q191224 ?p ?obj .
   # get the label
   # ?p sc:name ?name.
}
ORDER BY ?iname
LIMIT 500
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P1056'), ('name', 'product or material produced')]
# [('p', 'http://www.wikidata.org/prop/direct/P112'), ('name', 'founded by')]
# [('p', 'http://www.wikidata.org/prop/direct/P127'), ('name', 'owned by')]
# [('p', 'http://www.wikidata.org/prop/direct/P1454'), ('name', 'legal form')]
# [('p', 'http://www.wikidata.org/prop/direct/P154'), ('name', 'logo image')]
# [('p', 'http://www.wikidata.org/prop/direct/P159'), ('name', 'headquarters location')]
# [('p', 'http://www.wikidata.org/prop/direct/P17'), ('name', 'country')]
# [('p', 'http://www.wikidata.org/prop/direct/P1830'), ('name', 'owner of')]
# [('p', 'http://www.wikidata.org/prop/direct/P1889'), ('name', 'different from')]
# [('p', 'http://www.wikidata.org/prop/direct/P213'), ('name', 'ISNI')]
# [('p', 'http://www.wikidata.org/prop/direct/P214'), ('name', 'VIAF ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P244'), ('name', 'Library of Congress authority ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('name', 'instance of')]
# [('p', 'http://www.wikidata.org/prop/direct/P3417'), ('name', 'Quora topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P345'), ('name', 'IMDb ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P373'), ('name', 'Commons category')]
# [('p', 'http://www.wikidata.org/prop/direct/P452'), ('name', 'industry')]
# [('p', 'http://www.wikidata.org/prop/direct/P571'), ('name', 'inception')]
# [('p', 'http://www.wikidata.org/prop/direct/P646'), ('name', 'Freebase ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P691'), ('name', 'NKCR AUT ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P740'), ('name', 'location of formation')]
# [('p', 'http://www.wikidata.org/prop/direct/P749'), ('name', 'parent organization')]
# [('p', 'http://www.wikidata.org/prop/direct/P7859'), ('name', 'WorldCat Identities ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P856'), ('name', 'official website')]
# [('p', 'http://www.wikidata.org/prop/direct/P910'), ('name', "topic's main category")]
# 25

# %%
#Let see from who it's instance of. 
queryString = """
SELECT DISTINCT ?inst ?iname 
WHERE {
   # bind something
   wd:Q191224 ?p ?obj .
   # ?obj wdt:P31 ?inst.
   
   # get the label
   # ?inst sc:name ?iname.
}
ORDER BY ?iname
LIMIT 200
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('inst', 'http://www.wikidata.org/entity/Q35657'), ('iname', 'U.S. state')]
# [('inst', 'http://www.wikidata.org/entity/Q4167836'), ('iname', 'Wikimedia category')]
# [('inst', 'http://www.wikidata.org/entity/Q1107679'), ('iname', 'animation studio')]
# [('inst', 'http://www.wikidata.org/entity/Q1549591'), ('iname', 'big city')]
# [('inst', 'http://www.wikidata.org/entity/Q4830453'), ('iname', 'business')]
# [('inst', 'http://www.wikidata.org/entity/Q13218391'), ('iname', 'charter city')]
# [('inst', 'http://www.wikidata.org/entity/Q1093829'), ('iname', 'city of the United States')]
# [('inst', 'http://www.wikidata.org/entity/Q21980538'), ('iname', 'commercial organization')]
# [('inst', 'http://www.wikidata.org/entity/Q1520223'), ('iname', 'constitutional republic')]
# [('inst', 'http://www.wikidata.org/entity/Q7540587'), ('iname', 'corporate headquarters')]
# [('inst', 'http://www.wikidata.org/entity/Q6256'), ('iname', 'country')]
# [('inst', 'http://www.wikidata.org/entity/Q5255892'), ('iname', 'democratic republic')]
# [('inst', 'http://www.wikidata.org/entity/Q6881511'), ('iname', 'enterprise')]
# [('inst', 'http://www.wikidata.org/entity/Q512187'), ('iname', 'federal republic')]
# [('inst', 'http://www.wikidata.org/entity/Q1762059'), ('iname', 'film production company')]
# [('inst', 'http://www.wikidata.org/entity/Q375336'), ('iname', 'film studio')]
# [('inst', 'http://www.wikidata.org/entity/Q99541706'), ('iname', 'historical unrecognized state')]
# [('inst', 'http://www.wikidata.org/entity/Q5'), ('iname', 'human')]
# [('inst', 'http://www.wikidata.org/entity/Q268592'), ('iname', 'industry')]
# [('inst', 'http://www.wikidata.org/entity/Q12047392'), ('iname', 'legal form')]
# [('inst', 'http://www.wikidata.org/entity/Q1916382'), ('iname', 'media conglomerate')]
# [('inst', 'http://www.wikidata.org/entity/Q196600'), ('iname', 'media franchise')]
# [('inst', 'http://www.wikidata.org/entity/Q891723'), ('iname', 'public company')]
# [('inst', 'http://www.wikidata.org/entity/Q3624078'), ('iname', 'sovereign state')]
# [('inst', 'http://www.wikidata.org/entity/Q98449544'), ('iname', 'suburban community in the United States')]
# [('inst', 'http://www.wikidata.org/entity/Q1489259'), ('iname', 'superpower')]
# 26

# %%
#Let's explore film production company. 
queryString = """
SELECT DISTINCT ?p ?name
WHERE {
   # bind something
   wd:Q1762059 ?p ?obj .
   # get the label
   # ?p sc:name ?name.
}
ORDER BY ?iname
LIMIT 500
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P1889'), ('name', 'different from')]
# [('p', 'http://www.wikidata.org/prop/direct/P227'), ('name', 'GND ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('name', 'subclass of')]
# [('p', 'http://www.wikidata.org/prop/direct/P361'), ('name', 'part of')]
# [('p', 'http://www.wikidata.org/prop/direct/P373'), ('name', 'Commons category')]
# [('p', 'http://www.wikidata.org/prop/direct/P452'), ('name', 'industry')]
# [('p', 'http://www.wikidata.org/prop/direct/P646'), ('name', 'Freebase ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8408'), ('name', 'KBpedia ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P910'), ('name', "topic's main category")]
# 9

# %%
#Subclass of for film production company. 
queryString = """
SELECT DISTINCT ?inst ?iname 
WHERE {
   # bind something
   wd:Q1762059 ?p ?obj .
   # ?obj wdt:P279 ?inst.
   
   # get the label
   # ?inst sc:name ?iname.
}
ORDER BY ?iname
LIMIT 200
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('inst', 'http://www.wikidata.org/entity/Q20897549'), ('iname', 'art institution')]
# [('inst', 'http://www.wikidata.org/entity/Q783794'), ('iname', 'company')]
# [('inst', 'http://www.wikidata.org/entity/Q3152824'), ('iname', 'cultural institution')]
# [('inst', 'http://www.wikidata.org/entity/Q19595701'), ('iname', 'entertainment industry')]
# [('inst', 'http://www.wikidata.org/entity/Q104649845'), ('iname', 'film organization')]
# [('inst', 'http://www.wikidata.org/entity/Q1331793'), ('iname', 'media company')]
# [('inst', 'http://www.wikidata.org/entity/Q19364326'), ('iname', 'media studio facility')]
# 7

# %%
#let's see all the items that are subclass of film production company. 
queryString = """

SELECT DISTINCT ?production ?productionName 
WHERE {

   #bind something 
    # ?production wdt:P279 wd:Q1762059 .  
    
   # get the label 
    # ?production sc:name  ?productionName . 
   
}

LIMIT 100


"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('production', 'http://www.wikidata.org/entity/Q10689397'), ('productionName', 'television production company')]
# [('production', 'http://www.wikidata.org/entity/Q735427'), ('productionName', 'Poverty Row')]
# 2

# %% [markdown]
# Final query for this task

# %%
#I found the BGP for Television production company with last query.
queryString = """

SELECT DISTINCT ?production ?productionName 
WHERE {

   #bind something 
    # ?production wdt:P279 wd:Q1762059 . 
    
   # get the label 
    # ?production sc:name  ?productionName . 
   
}

LIMIT 100


"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('production', 'http://www.wikidata.org/entity/Q10689397'), ('productionName', 'television production company')]
# [('production', 'http://www.wikidata.org/entity/Q735427'), ('productionName', 'Poverty Row')]
# 2

# %% [markdown]
# ## Task 4
# Identify the BGP for film production company

# %%
#On the last query searching for the television production company I found the film production company between the instaces of walt disney pictures.
queryString = """
SELECT DISTINCT ?inst ?iname 
WHERE {
   # bind something
   wd:Q191224 ?p ?obj . #Walt disney pictures. 
   # ?obj wdt:P31 ?inst.
   
   # get the label
   # ?inst sc:name ?iname.
}
ORDER BY ?iname
LIMIT 200
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('inst', 'http://www.wikidata.org/entity/Q35657'), ('iname', 'U.S. state')]
# [('inst', 'http://www.wikidata.org/entity/Q4167836'), ('iname', 'Wikimedia category')]
# [('inst', 'http://www.wikidata.org/entity/Q1107679'), ('iname', 'animation studio')]
# [('inst', 'http://www.wikidata.org/entity/Q1549591'), ('iname', 'big city')]
# [('inst', 'http://www.wikidata.org/entity/Q4830453'), ('iname', 'business')]
# [('inst', 'http://www.wikidata.org/entity/Q13218391'), ('iname', 'charter city')]
# [('inst', 'http://www.wikidata.org/entity/Q1093829'), ('iname', 'city of the United States')]
# [('inst', 'http://www.wikidata.org/entity/Q21980538'), ('iname', 'commercial organization')]
# [('inst', 'http://www.wikidata.org/entity/Q1520223'), ('iname', 'constitutional republic')]
# [('inst', 'http://www.wikidata.org/entity/Q7540587'), ('iname', 'corporate headquarters')]
# [('inst', 'http://www.wikidata.org/entity/Q6256'), ('iname', 'country')]
# [('inst', 'http://www.wikidata.org/entity/Q5255892'), ('iname', 'democratic republic')]
# [('inst', 'http://www.wikidata.org/entity/Q6881511'), ('iname', 'enterprise')]
# [('inst', 'http://www.wikidata.org/entity/Q512187'), ('iname', 'federal republic')]
# [('inst', 'http://www.wikidata.org/entity/Q1762059'), ('iname', 'film production company')]
# [('inst', 'http://www.wikidata.org/entity/Q375336'), ('iname', 'film studio')]
# [('inst', 'http://www.wikidata.org/entity/Q99541706'), ('iname', 'historical unrecognized state')]
# [('inst', 'http://www.wikidata.org/entity/Q5'), ('iname', 'human')]
# [('inst', 'http://www.wikidata.org/entity/Q268592'), ('iname', 'industry')]
# [('inst', 'http://www.wikidata.org/entity/Q12047392'), ('iname', 'legal form')]
# [('inst', 'http://www.wikidata.org/entity/Q1916382'), ('iname', 'media conglomerate')]
# [('inst', 'http://www.wikidata.org/entity/Q196600'), ('iname', 'media franchise')]
# [('inst', 'http://www.wikidata.org/entity/Q891723'), ('iname', 'public company')]
# [('inst', 'http://www.wikidata.org/entity/Q3624078'), ('iname', 'sovereign state')]
# [('inst', 'http://www.wikidata.org/entity/Q98449544'), ('iname', 'suburban community in the United States')]
# [('inst', 'http://www.wikidata.org/entity/Q1489259'), ('iname', 'superpower')]
# 26

# %% [markdown]
# Final query for this task

# %%
# write your final query
queryString = """
SELECT DISTINCT ?inst ?iname 
WHERE {
   # bind something
   wd:Q191224 ?p ?obj .
   # ?obj wdt:P31 ?inst.
   
   VALUES ?inst {wd:Q1762059}
   
   # get the label
   # ?inst sc:name ?iname.
}
ORDER BY ?iname
LIMIT 200
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('inst', 'http://www.wikidata.org/entity/Q1762059'), ('iname', 'film production company')]
# 1

# %% [markdown]
# ## Task 5
# Find the top-5 companies (amongst television production company and film production company) which produced the highest number of crime films (the result set must be a list of triples company IRI, label and #crime film).

# %%
#first I need the identifier for Crime film. 
#Lets start looking throw the properties of The lion king, genre
queryString = """
SELECT DISTINCT ?inst ?iname 
WHERE {
   # bind something
   wd:Q36479 ?p ?obj .
   # ?obj wdt:P136 ?inst.
   
   # get the label
   # ?inst sc:name ?iname.
}
ORDER BY ?iname
LIMIT 200
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('inst', 'http://www.wikidata.org/entity/Q5073733'), ('iname', 'Character comedy')]
# [('inst', 'http://www.wikidata.org/entity/Q1152184'), ('iname', 'Shakespearean comedy')]
# [('inst', 'http://www.wikidata.org/entity/Q378988'), ('iname', 'adult contemporary music')]
# [('inst', 'http://www.wikidata.org/entity/Q319221'), ('iname', 'adventure film')]
# [('inst', 'http://www.wikidata.org/entity/Q53094'), ('iname', 'black comedy')]
# [('inst', 'http://www.wikidata.org/entity/Q40831'), ('iname', 'comedy')]
# [('inst', 'http://www.wikidata.org/entity/Q157443'), ('iname', 'comedy film')]
# [('inst', 'http://www.wikidata.org/entity/Q2975633'), ('iname', 'coming-of-age story')]
# [('inst', 'http://www.wikidata.org/entity/Q850412'), ('iname', 'contemporary R&B')]
# [('inst', 'http://www.wikidata.org/entity/Q1616750'), ('iname', 'deadpan')]
# [('inst', 'http://www.wikidata.org/entity/Q130232'), ('iname', 'drama')]
# [('inst', 'http://www.wikidata.org/entity/Q1361932'), ('iname', 'family film')]
# [('inst', 'http://www.wikidata.org/entity/Q76092'), ('iname', 'glam rock')]
# [('inst', 'http://www.wikidata.org/entity/Q83270'), ('iname', 'hard rock')]
# [('inst', 'http://www.wikidata.org/entity/Q17112404'), ('iname', 'insult comedy')]
# [('inst', 'http://www.wikidata.org/entity/Q191163'), ('iname', 'landscape art')]
# [('inst', 'http://www.wikidata.org/entity/Q2743'), ('iname', 'musical')]
# [('inst', 'http://www.wikidata.org/entity/Q1548170'), ('iname', 'musical comedy')]
# [('inst', 'http://www.wikidata.org/entity/Q2943864'), ('iname', 'news satire')]
# [('inst', 'http://www.wikidata.org/entity/Q4209421'), ('iname', 'observational comedy')]
# [('inst', 'http://www.wikidata.org/entity/Q7225114'), ('iname', 'political satire')]
# [('inst', 'http://www.wikidata.org/entity/Q37073'), ('iname', 'pop music')]
# [('inst', 'http://www.wikidata.org/entity/Q484641'), ('iname', 'pop rock')]
# [('inst', 'http://www.wikidata.org/entity/Q179461'), ('iname', 'religious text')]
# [('inst', 'http://www.wikidata.org/entity/Q45981'), ('iname', 'rhythm and blues')]
# [('inst', 'http://www.wikidata.org/entity/Q11399'), ('iname', 'rock music')]
# [('inst', 'http://www.wikidata.org/entity/Q1054574'), ('iname', 'romance film')]
# [('inst', 'http://www.wikidata.org/entity/Q128758'), ('iname', 'satire')]
# [('inst', 'http://www.wikidata.org/entity/Q217191'), ('iname', 'soft rock')]
# [('inst', 'http://www.wikidata.org/entity/Q61340552'), ('iname', 'stage and screen')]
# [('inst', 'http://www.wikidata.org/entity/Q1092460'), ('iname', 'surreal humour')]
# [('inst', 'http://www.wikidata.org/entity/Q80930'), ('iname', 'tragedy')]
# [('inst', 'http://www.wikidata.org/entity/Q205049'), ('iname', 'world music')]
# 33

# %%
#Lets see from who is intance musical Q2743
queryString = """
SELECT DISTINCT ?inst ?iname 
WHERE {
   # bind something
   wd:Q2743 ?p ?obj .
   # ?obj wdt:P31 ?inst.
   
   # get the label
   # ?inst sc:name ?iname.
}
ORDER BY ?iname
LIMIT 200
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('inst', 'http://www.wikidata.org/entity/Q19361238'), ('iname', 'Wikidata metaclass')]
# [('inst', 'http://www.wikidata.org/entity/Q4167836'), ('iname', 'Wikimedia category')]
# [('inst', 'http://www.wikidata.org/entity/Q19887878'), ('iname', 'Wikimedia infobox template')]
# [('inst', 'http://www.wikidata.org/entity/Q33532284'), ('iname', 'Wikimedia list of lists')]
# [('inst', 'http://www.wikidata.org/entity/Q151885'), ('iname', 'concept')]
# [('inst', 'http://www.wikidata.org/entity/Q5107'), ('iname', 'continent')]
# [('inst', 'http://www.wikidata.org/entity/Q201658'), ('iname', 'film genre')]
# [('inst', 'http://www.wikidata.org/entity/Q4263830'), ('iname', 'literary form')]
# [('inst', 'http://www.wikidata.org/entity/Q223393'), ('iname', 'literary genre')]
# [('inst', 'http://www.wikidata.org/entity/Q19478619'), ('iname', 'metaclass')]
# [('inst', 'http://www.wikidata.org/entity/Q188451'), ('iname', 'music genre')]
# [('inst', 'http://www.wikidata.org/entity/Q1239328'), ('iname', 'national encyclopedia')]
# [('inst', 'http://www.wikidata.org/entity/Q12737077'), ('iname', 'occupation')]
# [('inst', 'http://www.wikidata.org/entity/Q2418896'), ('iname', 'part of the world')]
# [('inst', 'http://www.wikidata.org/entity/Q28640'), ('iname', 'profession')]
# [('inst', 'http://www.wikidata.org/entity/Q107356781'), ('iname', 'song type')]
# [('inst', 'http://www.wikidata.org/entity/Q7777573'), ('iname', 'theatrical genre')]
# [('inst', 'http://www.wikidata.org/entity/Q1525071'), ('iname', 'universal encyclopedia')]
# 18

# %%
#Now we get all the instaces of film genre. 
queryString = """
SELECT DISTINCT ?inst ?iname 
WHERE {
   # bind something
   # ?inst wdt:P31 wd:Q201658.
   
   # get the label
   # ?inst sc:name ?iname.
}
ORDER BY ?iname
LIMIT 200
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('inst', 'http://www.wikidata.org/entity/Q4674071'), ('iname', 'Acid Western')]
# [('inst', 'http://www.wikidata.org/entity/Q108179271'), ('iname', 'Arthouse animation')]
# [('inst', 'http://www.wikidata.org/entity/Q223770'), ('iname', 'B movie')]
# [('inst', 'http://www.wikidata.org/entity/Q4836991'), ('iname', 'B western')]
# [('inst', 'http://www.wikidata.org/entity/Q3461143'), ('iname', 'BDSM film')]
# [('inst', 'http://www.wikidata.org/entity/Q31086090'), ('iname', 'Barbarian film')]
# [('inst', 'http://www.wikidata.org/entity/Q84041'), ('iname', 'Bavarian porn')]
# [('inst', 'http://www.wikidata.org/entity/Q7717463'), ('iname', 'Bible film')]
# [('inst', 'http://www.wikidata.org/entity/Q48816645'), ('iname', 'Black film')]
# [('inst', 'http://www.wikidata.org/entity/Q93196'), ('iname', 'Bollywood')]
# [('inst', 'http://www.wikidata.org/entity/Q16247268'), ('iname', 'Bollywood horror film')]
# [('inst', 'http://www.wikidata.org/entity/Q4950139'), ('iname', 'Bourekas film')]
# [('inst', 'http://www.wikidata.org/entity/Q849666'), ('iname', 'Brickfilm')]
# [('inst', 'http://www.wikidata.org/entity/Q580013'), ('iname', 'Bruceploitation')]
# [('inst', 'http://www.wikidata.org/entity/Q30726555'), ('iname', 'Category:Films set in antiquity')]
# [('inst', 'http://www.wikidata.org/entity/Q81552104'), ('iname', 'Chakma cinema')]
# [('inst', 'http://www.wikidata.org/entity/Q82721965'), ('iname', 'Chakwood')]
# [('inst', 'http://www.wikidata.org/entity/Q5070847'), ('iname', 'Chanchada')]
# [('inst', 'http://www.wikidata.org/entity/Q5104880'), ('iname', 'Chopsocky')]
# [('inst', 'http://www.wikidata.org/entity/Q28026639'), ('iname', 'Christmas film')]
# [('inst', 'http://www.wikidata.org/entity/Q2742446'), ('iname', 'Cinéma pur')]
# [('inst', 'http://www.wikidata.org/entity/Q1115187'), ('iname', "Commedia all'italiana")]
# [('inst', 'http://www.wikidata.org/entity/Q2991565'), ('iname', "Commedia sexy all'italiana")]
# [('inst', 'http://www.wikidata.org/entity/Q60753838'), ('iname', 'Computer screen film')]
# [('inst', 'http://www.wikidata.org/entity/Q1323308'), ('iname', 'Direct Cinema')]
# [('inst', 'http://www.wikidata.org/entity/Q1278107'), ('iname', 'Eastern')]
# [('inst', 'http://www.wikidata.org/entity/Q26268098'), ('iname', 'Eastern')]
# [('inst', 'http://www.wikidata.org/entity/Q759779'), ('iname', 'Enlightenment film')]
# [('inst', 'http://www.wikidata.org/entity/Q6722594'), ('iname', 'Euro War')]
# [('inst', 'http://www.wikidata.org/entity/Q5413472'), ('iname', 'European art cinema')]
# [('inst', 'http://www.wikidata.org/entity/Q5449041'), ('iname', 'Film à clef')]
# [('inst', 'http://www.wikidata.org/entity/Q11859599'), ('iname', 'Findie')]
# [('inst', 'http://www.wikidata.org/entity/Q23044991'), ('iname', 'Finnish horror film')]
# [('inst', 'http://www.wikidata.org/entity/Q5461696'), ('iname', 'Florida Western')]
# [('inst', 'http://www.wikidata.org/entity/Q1352102'), ('iname', 'Free Cinema')]
# [('inst', 'http://www.wikidata.org/entity/Q18331260'), ('iname', 'French comedy films')]
# [('inst', 'http://www.wikidata.org/entity/Q105320349'), ('iname', 'Gay-related film')]
# [('inst', 'http://www.wikidata.org/entity/Q2916932'), ('iname', 'Gendai-geki')]
# [('inst', 'http://www.wikidata.org/entity/Q2973158'), ('iname', 'Genre movie')]
# [('inst', 'http://www.wikidata.org/entity/Q5551875'), ('iname', 'German underground horror')]
# [('inst', 'http://www.wikidata.org/entity/Q5578091'), ('iname', 'Gokudō')]
# [('inst', 'http://www.wikidata.org/entity/Q5583970'), ('iname', 'Goona-goona epic')]
# [('inst', 'http://www.wikidata.org/entity/Q25230421'), ('iname', 'Gothic romance film')]
# [('inst', 'http://www.wikidata.org/entity/Q3778115'), ('iname', 'Gross out')]
# [('inst', 'http://www.wikidata.org/entity/Q5622029'), ('iname', 'Guy-cry film')]
# [('inst', 'http://www.wikidata.org/entity/Q25636204'), ('iname', 'Haredi cinema')]
# [('inst', 'http://www.wikidata.org/entity/Q304538'), ('iname', 'Heimatfilm')]
# [('inst', 'http://www.wikidata.org/entity/Q1621121'), ('iname', 'Hitchcockian film')]
# [('inst', 'http://www.wikidata.org/entity/Q3772578'), ('iname', 'Home movies')]
# [('inst', 'http://www.wikidata.org/entity/Q167776'), ('iname', 'Italian neorealism')]
# [('inst', 'http://www.wikidata.org/entity/Q2584671'), ('iname', 'Japanese horror')]
# [('inst', 'http://www.wikidata.org/entity/Q629917'), ('iname', 'Jidaigeki')]
# [('inst', 'http://www.wikidata.org/entity/Q28164087'), ('iname', 'Jollywood')]
# [('inst', 'http://www.wikidata.org/entity/Q1065444'), ('iname', 'Kaiju')]
# [('inst', 'http://www.wikidata.org/entity/Q1502766'), ('iname', 'Kammerspielfilm')]
# [('inst', 'http://www.wikidata.org/entity/Q5620056'), ('iname', 'Korean horror')]
# [('inst', 'http://www.wikidata.org/entity/Q20442589'), ('iname', 'LGBT-related film')]
# [('inst', 'http://www.wikidata.org/entity/Q102141681'), ('iname', 'Lesbian and Gay Film')]
# [('inst', 'http://www.wikidata.org/entity/Q25975'), ('iname', "Let's Play")]
# [('inst', 'http://www.wikidata.org/entity/Q6696549'), ('iname', 'Lucha film')]
# [('inst', 'http://www.wikidata.org/entity/Q3028680'), ('iname', 'Masala')]
# [('inst', 'http://www.wikidata.org/entity/Q4044177'), ('iname', 'Mexploitation')]
# [('inst', 'http://www.wikidata.org/entity/Q11894225'), ('iname', 'Military comedy')]
# [('inst', 'http://www.wikidata.org/entity/Q1550219'), ('iname', 'Mo lei tau')]
# [('inst', 'http://www.wikidata.org/entity/Q6926334'), ('iname', 'Mouth of Garbage film')]
# [('inst', 'http://www.wikidata.org/entity/Q1108032'), ('iname', 'Mumblecore')]
# [('inst', 'http://www.wikidata.org/entity/Q6943011'), ('iname', 'Muslim social')]
# [('inst', 'http://www.wikidata.org/entity/Q535518'), ('iname', 'Nazi exploitation')]
# [('inst', 'http://www.wikidata.org/entity/Q2724311'), ('iname', 'New Queer Cinema')]
# [('inst', 'http://www.wikidata.org/entity/Q3344204'), ('iname', 'Northern')]
# [('inst', 'http://www.wikidata.org/entity/Q2002987'), ('iname', 'Novo Cinema')]
# [('inst', 'http://www.wikidata.org/entity/Q7116678'), ('iname', 'Ozploitation')]
# [('inst', 'http://www.wikidata.org/entity/Q7134948'), ('iname', 'Parallel Cinema')]
# [('inst', 'http://www.wikidata.org/entity/Q1433443'), ('iname', 'Peplum film genre')]
# [('inst', 'http://www.wikidata.org/entity/Q5712461'), ('iname', 'Persian Film')]
# [('inst', 'http://www.wikidata.org/entity/Q7234396'), ('iname', 'Postmodernist film')]
# [('inst', 'http://www.wikidata.org/entity/Q1456178'), ('iname', 'Prussian film')]
# [('inst', 'http://www.wikidata.org/entity/Q3677206'), ('iname', 'Quinqui (film genre)')]
# [('inst', 'http://www.wikidata.org/entity/Q107278078'), ('iname', 'Realist film')]
# [('inst', 'http://www.wikidata.org/entity/Q268854'), ('iname', 'Red Western')]
# [('inst', 'http://www.wikidata.org/entity/Q66425231'), ('iname', 'Redsploitation')]
# [('inst', 'http://www.wikidata.org/entity/Q491158'), ('iname', 'Revisionist Western')]
# [('inst', 'http://www.wikidata.org/entity/Q7379160'), ('iname', 'Rumberas film')]
# [('inst', 'http://www.wikidata.org/entity/Q18355406'), ('iname', 'Satanic film')]
# [('inst', 'http://www.wikidata.org/entity/Q2263701'), ('iname', 'Sceneggiata')]
# [('inst', 'http://www.wikidata.org/entity/Q2145099'), ('iname', 'Sex report film')]
# [('inst', 'http://www.wikidata.org/entity/Q6142791'), ('iname', 'Shinpa')]
# [('inst', 'http://www.wikidata.org/entity/Q3482453'), ('iname', 'Shomin-geki')]
# [('inst', 'http://www.wikidata.org/entity/Q65088741'), ('iname', 'Skate video')]
# [('inst', 'http://www.wikidata.org/entity/Q3964495'), ('iname', 'Somaliwood')]
# [('inst', 'http://www.wikidata.org/entity/Q7568398'), ('iname', 'South Seas')]
# [('inst', 'http://www.wikidata.org/entity/Q4235011'), ('iname', 'Space Western')]
# [('inst', 'http://www.wikidata.org/entity/Q10674355'), ('iname', 'Spanish horror movie')]
# [('inst', 'http://www.wikidata.org/entity/Q2000178'), ('iname', 'Telefoni Bianchi')]
# [('inst', 'http://www.wikidata.org/entity/Q61117528'), ('iname', 'Ukrainian poetic cinema')]
# [('inst', 'http://www.wikidata.org/entity/Q370630'), ('iname', 'Web film')]
# [('inst', 'http://www.wikidata.org/entity/Q775169'), ('iname', 'Weird West')]
# [('inst', 'http://www.wikidata.org/entity/Q172980'), ('iname', 'Western film')]
# [('inst', 'http://www.wikidata.org/entity/Q1669985'), ('iname', 'Wiener Film')]
# [('inst', 'http://www.wikidata.org/entity/Q1451709'), ('iname', "Women's cinema")]
# [('inst', 'http://www.wikidata.org/entity/Q1117103'), ('iname', 'Z movie')]
# [('inst', 'http://www.wikidata.org/entity/Q8066387'), ('iname', 'Zapata Western')]
# [('inst', 'http://www.wikidata.org/entity/Q16824564'), ('iname', 'absolute film')]
# [('inst', 'http://www.wikidata.org/entity/Q332564'), ('iname', 'abstract film')]
# [('inst', 'http://www.wikidata.org/entity/Q2678111'), ('iname', 'action comedy film')]
# [('inst', 'http://www.wikidata.org/entity/Q188473'), ('iname', 'action film')]
# [('inst', 'http://www.wikidata.org/entity/Q78461348'), ('iname', 'action-adventure film')]
# [('inst', 'http://www.wikidata.org/entity/Q108357966'), ('iname', 'actual play')]
# [('inst', 'http://www.wikidata.org/entity/Q4677832'), ('iname', 'actuality film')]
# [('inst', 'http://www.wikidata.org/entity/Q3249257'), ('iname', 'adult animation')]
# [('inst', 'http://www.wikidata.org/entity/Q319221'), ('iname', 'adventure film')]
# [('inst', 'http://www.wikidata.org/entity/Q20656352'), ('iname', 'alternate history film')]
# [('inst', 'http://www.wikidata.org/entity/Q18466840'), ('iname', 'alternative cinema')]
# [('inst', 'http://www.wikidata.org/entity/Q455620'), ('iname', 'amateur film')]
# [('inst', 'http://www.wikidata.org/entity/Q56240556'), ('iname', 'amusement ride film')]
# [('inst', 'http://www.wikidata.org/entity/Q11857634'), ('iname', 'animal fantasy')]
# [('inst', 'http://www.wikidata.org/entity/Q17175676'), ('iname', 'animated cartoon')]
# [('inst', 'http://www.wikidata.org/entity/Q4765076'), ('iname', 'animated documentary')]
# [('inst', 'http://www.wikidata.org/entity/Q1107'), ('iname', 'anime')]
# [('inst', 'http://www.wikidata.org/entity/Q20650540'), ('iname', 'anime film')]
# [('inst', 'http://www.wikidata.org/entity/Q336144'), ('iname', 'anthology film')]
# [('inst', 'http://www.wikidata.org/entity/Q4774498'), ('iname', 'anti-war film')]
# [('inst', 'http://www.wikidata.org/entity/Q47009776'), ('iname', 'apocalyptic film')]
# [('inst', 'http://www.wikidata.org/entity/Q1135802'), ('iname', 'art film')]
# [('inst', 'http://www.wikidata.org/entity/Q4797626'), ('iname', 'arthouse action film')]
# [('inst', 'http://www.wikidata.org/entity/Q3076696'), ('iname', 'association football film')]
# [('inst', 'http://www.wikidata.org/entity/Q13209138'), ('iname', 'auteur film')]
# [('inst', 'http://www.wikidata.org/entity/Q3072024'), ('iname', 'autobiographical film')]
# [('inst', 'http://www.wikidata.org/entity/Q4839755'), ('iname', 'backstage musical')]
# [('inst', 'http://www.wikidata.org/entity/Q798555'), ('iname', 'backwoods film')]
# [('inst', 'http://www.wikidata.org/entity/Q4840473'), ('iname', 'bad girl movie')]
# [('inst', 'http://www.wikidata.org/entity/Q4484381'), ('iname', 'ballet film')]
# [('inst', 'http://www.wikidata.org/entity/Q108258724'), ('iname', 'bandy film')]
# [('inst', 'http://www.wikidata.org/entity/Q4875794'), ('iname', 'beach party film')]
# [('inst', 'http://www.wikidata.org/entity/Q645928'), ('iname', 'biographical film')]
# [('inst', 'http://www.wikidata.org/entity/Q5778924'), ('iname', 'black comedy film')]
# [('inst', 'http://www.wikidata.org/entity/Q883179'), ('iname', 'blaxploitation')]
# [('inst', 'http://www.wikidata.org/entity/Q4925568'), ('iname', 'blaxploitation horror film')]
# [('inst', 'http://www.wikidata.org/entity/Q4930081'), ('iname', 'blue film')]
# [('inst', 'http://www.wikidata.org/entity/Q102260466'), ('iname', 'body horror film')]
# [('inst', 'http://www.wikidata.org/entity/Q895583'), ('iname', 'boxing film')]
# [('inst', 'http://www.wikidata.org/entity/Q18398246'), ('iname', 'bromantic comedy')]
# [('inst', 'http://www.wikidata.org/entity/Q4984974'), ('iname', 'buddy cop film')]
# [('inst', 'http://www.wikidata.org/entity/Q663106'), ('iname', 'buddy film')]
# [('inst', 'http://www.wikidata.org/entity/Q1480924'), ('iname', 'cabview film')]
# [('inst', 'http://www.wikidata.org/entity/Q1723850'), ('iname', 'cannibal film')]
# [('inst', 'http://www.wikidata.org/entity/Q108202399'), ('iname', 'cheerleading films')]
# [('inst', 'http://www.wikidata.org/entity/Q2075808'), ('iname', 'chick flick')]
# [('inst', 'http://www.wikidata.org/entity/Q4207328'), ('iname', 'child erotica')]
# [('inst', 'http://www.wikidata.org/entity/Q2143665'), ('iname', "children's film")]
# [('inst', 'http://www.wikidata.org/entity/Q18466908'), ('iname', 'cinema marginal')]
# [('inst', 'http://www.wikidata.org/entity/Q1957385'), ('iname', 'cinematic fairy tale')]
# [('inst', 'http://www.wikidata.org/entity/Q1092621'), ('iname', 'cinéma vérité')]
# [('inst', 'http://www.wikidata.org/entity/Q107022805'), ('iname', 'circus film')]
# [('inst', 'http://www.wikidata.org/entity/Q18089617'), ('iname', 'clay animation film')]
# [('inst', 'http://www.wikidata.org/entity/Q5145881'), ('iname', 'collage film')]
# [('inst', 'http://www.wikidata.org/entity/Q2973149'), ('iname', 'colonial cinema')]
# [('inst', 'http://www.wikidata.org/entity/Q157443'), ('iname', 'comedy film')]
# [('inst', 'http://www.wikidata.org/entity/Q108466999'), ('iname', 'comedy horror film')]
# [('inst', 'http://www.wikidata.org/entity/Q56296585'), ('iname', 'comedy of error')]
# [('inst', 'http://www.wikidata.org/entity/Q2991535'), ('iname', 'comedy of intrigue')]
# [('inst', 'http://www.wikidata.org/entity/Q5151497'), ('iname', 'comedy of remarriage')]
# [('inst', 'http://www.wikidata.org/entity/Q16950433'), ('iname', 'comedy thriller')]
# [('inst', 'http://www.wikidata.org/entity/Q859369'), ('iname', 'comedy-drama')]
# [('inst', 'http://www.wikidata.org/entity/Q3745400'), ('iname', 'comical film')]
# [('inst', 'http://www.wikidata.org/entity/Q102429885'), ('iname', 'coming-of-age film')]
# [('inst', 'http://www.wikidata.org/entity/Q455315'), ('iname', 'compilation film')]
# [('inst', 'http://www.wikidata.org/entity/Q5156753'), ('iname', 'composite film')]
# [('inst', 'http://www.wikidata.org/entity/Q28968258'), ('iname', 'computer-animated film')]
# [('inst', 'http://www.wikidata.org/entity/Q430525'), ('iname', 'concert film')]
# [('inst', 'http://www.wikidata.org/entity/Q2593937'), ('iname', 'conspiracy fiction')]
# [('inst', 'http://www.wikidata.org/entity/Q2907760'), ('iname', 'corporate video')]
# [('inst', 'http://www.wikidata.org/entity/Q542475'), ('iname', 'costume drama')]
# [('inst', 'http://www.wikidata.org/entity/Q959790'), ('iname', 'crime film')]
# [('inst', 'http://www.wikidata.org/entity/Q19367312'), ('iname', 'crime thriller')]
# [('inst', 'http://www.wikidata.org/entity/Q1788980'), ('iname', 'crime-comedy film')]
# [('inst', 'http://www.wikidata.org/entity/Q7888483'), ('iname', 'crush film')]
# [('inst', 'http://www.wikidata.org/entity/Q15804095'), ('iname', 'culture clash comedy')]
# [('inst', 'http://www.wikidata.org/entity/Q3072043'), ('iname', 'dance film')]
# [('inst', 'http://www.wikidata.org/entity/Q45893900'), ('iname', 'deaf cinema')]
# [('inst', 'http://www.wikidata.org/entity/Q25533274'), ('iname', 'detective film')]
# [('inst', 'http://www.wikidata.org/entity/Q846544'), ('iname', 'disaster film')]
# [('inst', 'http://www.wikidata.org/entity/Q622370'), ('iname', 'docudrama')]
# [('inst', 'http://www.wikidata.org/entity/Q472637'), ('iname', 'docufiction')]
# [('inst', 'http://www.wikidata.org/entity/Q93204'), ('iname', 'documentary film')]
# [('inst', 'http://www.wikidata.org/entity/Q130232'), ('iname', 'drama')]
# [('inst', 'http://www.wikidata.org/entity/Q106878648'), ('iname', 'dramatization')]
# [('inst', 'http://www.wikidata.org/entity/Q18620604'), ('iname', 'dramatization')]
# [('inst', 'http://www.wikidata.org/entity/Q20443008'), ('iname', 'dystopian film')]
# [('inst', 'http://www.wikidata.org/entity/Q1153173'), ('iname', 'educational entertainment')]
# [('inst', 'http://www.wikidata.org/entity/Q596138'), ('iname', 'educational film')]
# [('inst', 'http://www.wikidata.org/entity/Q652256'), ('iname', 'epic film')]
# [('inst', 'http://www.wikidata.org/entity/Q599558'), ('iname', 'erotic film')]
# [('inst', 'http://www.wikidata.org/entity/Q11356864'), ('iname', 'essay film')]
# [('inst', 'http://www.wikidata.org/entity/Q3059309'), ('iname', 'ethnofiction')]
# [('inst', 'http://www.wikidata.org/entity/Q1371394'), ('iname', 'ethnographic film')]
# [('inst', 'http://www.wikidata.org/entity/Q3677202'), ('iname', 'eurospy film')]
# [('inst', 'http://www.wikidata.org/entity/Q790192'), ('iname', 'experimental film')]
# [('inst', 'http://www.wikidata.org/entity/Q1067324'), ('iname', 'exploitation film')]
# [('inst', 'http://www.wikidata.org/entity/Q1361932'), ('iname', 'family film')]
# 200

# %%
#Now we have crime film (Q959790), the next step is to get all the movies that has in the property genre crime film to get all the crime films 
queryString = """
SELECT DISTINCT ?movie ?movieName 
WHERE {
   # bind something
   # ?movie wdt:P136 wd:Q959790.
   
   # get the label
   # ?movie sc:name ?movieName.
}
ORDER BY ?movieName
LIMIT 200
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('movie', 'http://www.wikidata.org/entity/Q16691116'), ('movieName', '"Dream" Agency')]
# [('movie', 'http://www.wikidata.org/entity/Q99644282'), ('movieName', '#martyisdead')]
# [('movie', 'http://www.wikidata.org/entity/Q2966024'), ('movieName', "'R Xmas")]
# [('movie', 'http://www.wikidata.org/entity/Q426517'), ('movieName', '...And Justice for All')]
# [('movie', 'http://www.wikidata.org/entity/Q4545163'), ('movieName', '...tick...tick...tick...')]
# [('movie', 'http://www.wikidata.org/entity/Q1537986'), ('movieName', '.45')]
# [('movie', 'http://www.wikidata.org/entity/Q4545428'), ('movieName', '.com for Murder')]
# [('movie', 'http://www.wikidata.org/entity/Q27588607'), ('movieName', '1 + 3 = 4')]
# [('movie', 'http://www.wikidata.org/entity/Q4595935'), ('movieName', '1 Day')]
# [('movie', 'http://www.wikidata.org/entity/Q2806572'), ('movieName', '1-Ichi')]
# [('movie', 'http://www.wikidata.org/entity/Q27890273'), ('movieName', '10 Kalpanakal')]
# [('movie', 'http://www.wikidata.org/entity/Q2422607'), ('movieName', '10 Rillington Place')]
# [('movie', 'http://www.wikidata.org/entity/Q2351514'), ('movieName', '10 to Midnight')]
# [('movie', 'http://www.wikidata.org/entity/Q1785876'), ('movieName', '10th & Wolf')]
# [('movie', 'http://www.wikidata.org/entity/Q114497'), ('movieName', '11 Uhr 20')]
# [('movie', 'http://www.wikidata.org/entity/Q4548000'), ('movieName', '11th Victim')]
# [('movie', 'http://www.wikidata.org/entity/Q175014'), ('movieName', '12')]
# [('movie', 'http://www.wikidata.org/entity/Q19961236'), ('movieName', '12 Citizens')]
# [('movie', 'http://www.wikidata.org/entity/Q30807781'), ('movieName', '12 Past Midnight')]
# [('movie', 'http://www.wikidata.org/entity/Q245187'), ('movieName', '12 Rounds')]
# [('movie', 'http://www.wikidata.org/entity/Q14512003'), ('movieName', '12 Rounds 2: Reloaded')]
# [('movie', 'http://www.wikidata.org/entity/Q245197'), ('movieName', '12 Winter')]
# [('movie', 'http://www.wikidata.org/entity/Q3597232'), ('movieName', '12.10')]
# [('movie', 'http://www.wikidata.org/entity/Q2807300'), ('movieName', '125')]
# [('movie', 'http://www.wikidata.org/entity/Q4549340'), ('movieName', '13 Dead Men')]
# [('movie', 'http://www.wikidata.org/entity/Q4549377'), ('movieName', '13 West Street')]
# [('movie', 'http://www.wikidata.org/entity/Q3819803'), ('movieName', '15 Maiden Lane')]
# [('movie', 'http://www.wikidata.org/entity/Q180395'), ('movieName', '15 Minutes')]
# [('movie', 'http://www.wikidata.org/entity/Q27952990'), ('movieName', '15 Years and 3 Hours Ago')]
# [('movie', 'http://www.wikidata.org/entity/Q169000'), ('movieName', '16 Blocks')]
# [('movie', 'http://www.wikidata.org/entity/Q4029258'), ('movieName', '1814')]
# [('movie', 'http://www.wikidata.org/entity/Q28862065'), ('movieName', '1890')]
# [('movie', 'http://www.wikidata.org/entity/Q4595704'), ('movieName', '19 Red Roses')]
# [('movie', 'http://www.wikidata.org/entity/Q15232860'), ('movieName', '19-Nineteen')]
# [('movie', 'http://www.wikidata.org/entity/Q4589249'), ('movieName', '1994 Baker Street: Sherlock Holmes Returns')]
# [('movie', 'http://www.wikidata.org/entity/Q106805210'), ('movieName', '1997 Trilogy')]
# [('movie', 'http://www.wikidata.org/entity/Q39071515'), ('movieName', '2')]
# [('movie', 'http://www.wikidata.org/entity/Q222867'), ('movieName', '2 Fast 2 Furious')]
# [('movie', 'http://www.wikidata.org/entity/Q3598715'), ('movieName', '2 Guns')]
# [('movie', 'http://www.wikidata.org/entity/Q213999'), ('movieName', '21')]
# [('movie', 'http://www.wikidata.org/entity/Q214013'), ('movieName', '21 Grams')]
# [('movie', 'http://www.wikidata.org/entity/Q214014'), ('movieName', '21 Jump Street')]
# [('movie', 'http://www.wikidata.org/entity/Q24708038'), ('movieName', '219')]
# [('movie', 'http://www.wikidata.org/entity/Q215319'), ('movieName', '22 Bullets')]
# [('movie', 'http://www.wikidata.org/entity/Q48818107'), ('movieName', '22 July')]
# [('movie', 'http://www.wikidata.org/entity/Q215289'), ('movieName', '22:43 – Das Schicksal hat einen Plan')]
# [('movie', 'http://www.wikidata.org/entity/Q3576935'), ('movieName', '23 Paces to Baker Street')]
# [('movie', 'http://www.wikidata.org/entity/Q39072655'), ('movieName', '23h58')]
# [('movie', 'http://www.wikidata.org/entity/Q18349020'), ('movieName', '24 Exposures')]
# [('movie', 'http://www.wikidata.org/entity/Q4631874'), ('movieName', '24 Hours in London')]
# [('movie', 'http://www.wikidata.org/entity/Q218458'), ('movieName', '25th Hour')]
# [('movie', 'http://www.wikidata.org/entity/Q21511401'), ('movieName', '27 Rue de la Paix')]
# [('movie', 'http://www.wikidata.org/entity/Q744836'), ('movieName', '3 Blind Mice')]
# [('movie', 'http://www.wikidata.org/entity/Q27590375'), ('movieName', '3 Days in Havana')]
# [('movie', 'http://www.wikidata.org/entity/Q489818'), ('movieName', '3-Iron')]
# [('movie', 'http://www.wikidata.org/entity/Q224133'), ('movieName', '30 Minutes or Less')]
# [('movie', 'http://www.wikidata.org/entity/Q16117400'), ('movieName', '31/12')]
# [('movie', 'http://www.wikidata.org/entity/Q14949825'), ('movieName', '36 Hours')]
# [('movie', 'http://www.wikidata.org/entity/Q227548'), ('movieName', '36 Quai des Orfèvres')]
# [('movie', 'http://www.wikidata.org/entity/Q746029'), ('movieName', '3:10 to Yuma')]
# [('movie', 'http://www.wikidata.org/entity/Q234789'), ('movieName', '44 Inch Chest')]
# [('movie', 'http://www.wikidata.org/entity/Q234800'), ('movieName', '44 Minutes: The North Hollywood Shoot-Out')]
# [('movie', 'http://www.wikidata.org/entity/Q6529759'), ('movieName', '45 Yom')]
# [('movie', 'http://www.wikidata.org/entity/Q56312417'), ('movieName', "48, avenue de l'Opéra")]
# [('movie', 'http://www.wikidata.org/entity/Q4639403'), ('movieName', '4th Period Mystery')]
# [('movie', 'http://www.wikidata.org/entity/Q4641158'), ('movieName', '5 Steps to Danger')]
# [('movie', 'http://www.wikidata.org/entity/Q242764'), ('movieName', '52 Pick-Up')]
# [('movie', 'http://www.wikidata.org/entity/Q967527'), ('movieName', '6,000 Enemies')]
# [('movie', 'http://www.wikidata.org/entity/Q31271052'), ('movieName', '68 Kill')]
# [('movie', 'http://www.wikidata.org/entity/Q2818330'), ('movieName', '7 Khoon Maaf')]
# [('movie', 'http://www.wikidata.org/entity/Q56307532'), ('movieName', '7 Minutes')]
# [('movie', 'http://www.wikidata.org/entity/Q3838019'), ('movieName', '711 Ocean Drive')]
# [('movie', 'http://www.wikidata.org/entity/Q4643582'), ('movieName', '77 Park Lane')]
# [('movie', 'http://www.wikidata.org/entity/Q18288673'), ('movieName', '77 Rue Chalgrin')]
# [('movie', 'http://www.wikidata.org/entity/Q16057752'), ('movieName', '7th Day')]
# [('movie', 'http://www.wikidata.org/entity/Q2478733'), ('movieName', '8 Heads in a Duffel Bag')]
# [('movie', 'http://www.wikidata.org/entity/Q274904'), ('movieName', '8 Million Ways to Die')]
# [('movie', 'http://www.wikidata.org/entity/Q274895'), ('movieName', '8 Women')]
# [('movie', 'http://www.wikidata.org/entity/Q18511181'), ('movieName', '8 of Diamonds')]
# [('movie', 'http://www.wikidata.org/entity/Q11849616'), ('movieName', '8-Ball')]
# [('movie', 'http://www.wikidata.org/entity/Q274400'), ('movieName', '88 Minutes')]
# [('movie', 'http://www.wikidata.org/entity/Q274973'), ('movieName', '8mm')]
# [('movie', 'http://www.wikidata.org/entity/Q11323655'), ('movieName', '9 Souls')]
# [('movie', 'http://www.wikidata.org/entity/Q4646457'), ('movieName', '9 millimeter')]
# [('movie', 'http://www.wikidata.org/entity/Q1466657'), ('movieName', '9 to 5')]
# [('movie', 'http://www.wikidata.org/entity/Q15260460'), ('movieName', '90 Minutes Stop')]
# [('movie', 'http://www.wikidata.org/entity/Q4646086'), ('movieName', '96 Minutes')]
# [('movie', 'http://www.wikidata.org/entity/Q16303495'), ('movieName', '96 hours')]
# [('movie', 'http://www.wikidata.org/entity/Q4646304'), ('movieName', '99 River Street')]
# [('movie', 'http://www.wikidata.org/entity/Q4354219'), ('movieName', '99 and 44/100% Dead')]
# [('movie', 'http://www.wikidata.org/entity/Q641346'), ('movieName', 'A Better Tomorrow')]
# [('movie', 'http://www.wikidata.org/entity/Q787091'), ('movieName', 'A Better Tomorrow 2')]
# [('movie', 'http://www.wikidata.org/entity/Q751064'), ('movieName', 'A Better Tomorrow 3')]
# [('movie', 'http://www.wikidata.org/entity/Q56276045'), ('movieName', 'A Bid for Fortune')]
# [('movie', 'http://www.wikidata.org/entity/Q4655520'), ('movieName', 'A Bloody Aria')]
# [('movie', 'http://www.wikidata.org/entity/Q4655525'), ('movieName', 'A Blueprint for Murder')]
# [('movie', 'http://www.wikidata.org/entity/Q2948074'), ('movieName', 'A Boy Called Hate')]
# [('movie', 'http://www.wikidata.org/entity/Q1130705'), ('movieName', 'A Bronx Tale')]
# [('movie', 'http://www.wikidata.org/entity/Q16847297'), ('movieName', 'A Brooklyn State of Mind')]
# [('movie', 'http://www.wikidata.org/entity/Q24706225'), ('movieName', 'A Brush Soaked in Carmine')]
# [('movie', 'http://www.wikidata.org/entity/Q4655672'), ('movieName', 'A Bullet Is Waiting')]
# [('movie', 'http://www.wikidata.org/entity/Q16681862'), ('movieName', 'A Bullet Through the Heart')]
# [('movie', 'http://www.wikidata.org/entity/Q4004029'), ('movieName', 'A Bullet for Pretty Boy')]
# [('movie', 'http://www.wikidata.org/entity/Q3549350'), ('movieName', 'A Bullet in the Gun Barrel')]
# [('movie', 'http://www.wikidata.org/entity/Q20876053'), ('movieName', 'A Canine Sherlock Holmes')]
# [('movie', 'http://www.wikidata.org/entity/Q4655746'), ('movieName', 'A Case of Deadly Force')]
# [('movie', 'http://www.wikidata.org/entity/Q16020802'), ('movieName', 'A Case of Identity')]
# [('movie', 'http://www.wikidata.org/entity/Q4655756'), ('movieName', 'A Case of Rape')]
# [('movie', 'http://www.wikidata.org/entity/Q300345'), ('movieName', 'A Cat in Paris')]
# [('movie', 'http://www.wikidata.org/entity/Q651353'), ('movieName', 'A Certain Mister')]
# [('movie', 'http://www.wikidata.org/entity/Q3548425'), ('movieName', 'A Certain Monsieur Jo')]
# [('movie', 'http://www.wikidata.org/entity/Q45249801'), ('movieName', 'A Child is Wanted')]
# [('movie', 'http://www.wikidata.org/entity/Q181086'), ('movieName', 'A Clockwork Orange')]
# [('movie', 'http://www.wikidata.org/entity/Q4655976'), ('movieName', 'A Close Call for Boston Blackie')]
# [('movie', 'http://www.wikidata.org/entity/Q4656045'), ('movieName', 'A Company Man')]
# [('movie', 'http://www.wikidata.org/entity/Q300377'), ('movieName', 'A Crime')]
# [('movie', 'http://www.wikidata.org/entity/Q200980'), ('movieName', 'A Crime')]
# [('movie', 'http://www.wikidata.org/entity/Q4656244'), ('movieName', 'A Dangerous Summer')]
# [('movie', 'http://www.wikidata.org/entity/Q15791288'), ('movieName', 'A Daring Daylight Burglary')]
# [('movie', 'http://www.wikidata.org/entity/Q4656269'), ('movieName', 'A Date with the Falcon')]
# [('movie', 'http://www.wikidata.org/entity/Q4656276'), ('movieName', 'A Daughter of Eve')]
# [('movie', 'http://www.wikidata.org/entity/Q63398433'), ('movieName', 'A Daughter of the Law')]
# [('movie', 'http://www.wikidata.org/entity/Q4656359'), ('movieName', 'A Death in Canaan')]
# [('movie', 'http://www.wikidata.org/entity/Q22340294'), ('movieName', 'A Decent Man')]
# [('movie', 'http://www.wikidata.org/entity/Q10468625'), ('movieName', 'A Double-Dyed Deceiver')]
# [('movie', 'http://www.wikidata.org/entity/Q1964370'), ('movieName', 'A Family Torn Apart')]
# [('movie', 'http://www.wikidata.org/entity/Q626394'), ('movieName', 'A Family of Cops')]
# [('movie', 'http://www.wikidata.org/entity/Q1213727'), ('movieName', 'A Fatal Assignment')]
# [('movie', 'http://www.wikidata.org/entity/Q4656714'), ('movieName', 'A Fever in the Blood')]
# [('movie', 'http://www.wikidata.org/entity/Q108946'), ('movieName', 'A Few Good Men')]
# [('movie', 'http://www.wikidata.org/entity/Q4003704'), ('movieName', 'A Fine Mess')]
# [('movie', 'http://www.wikidata.org/entity/Q22973058'), ('movieName', 'A Forbidden Love')]
# [('movie', 'http://www.wikidata.org/entity/Q1767167'), ('movieName', 'A Force of One')]
# [('movie', 'http://www.wikidata.org/entity/Q860764'), ('movieName', 'A Free Soul')]
# [('movie', 'http://www.wikidata.org/entity/Q2418057'), ('movieName', 'A Friend to Die For')]
# [('movie', 'http://www.wikidata.org/entity/Q3007792'), ('movieName', 'A Fugitive from the Past')]
# [('movie', 'http://www.wikidata.org/entity/Q4656910'), ('movieName', 'A Gamble with Hearts')]
# [('movie', 'http://www.wikidata.org/entity/Q39047111'), ('movieName', 'A Game without Rules')]
# [('movie', 'http://www.wikidata.org/entity/Q593'), ('movieName', 'A Gang Story')]
# [('movie', 'http://www.wikidata.org/entity/Q610700'), ('movieName', 'A Gangstergirl')]
# [('movie', 'http://www.wikidata.org/entity/Q16250679'), ('movieName', 'A Gentle Gangster')]
# [('movie', 'http://www.wikidata.org/entity/Q4656965'), ('movieName', 'A Gentleman After Dark')]
# [('movie', 'http://www.wikidata.org/entity/Q4656975'), ('movieName', 'A Gentleman of Paris')]
# [('movie', 'http://www.wikidata.org/entity/Q47004710'), ('movieName', 'A Glimpse of Paradise')]
# [('movie', 'http://www.wikidata.org/entity/Q19363532'), ('movieName', 'A Good Man')]
# [('movie', 'http://www.wikidata.org/entity/Q54020397'), ('movieName', 'A Good Thief')]
# [('movie', 'http://www.wikidata.org/entity/Q1962699'), ('movieName', 'A Grande Arte')]
# [('movie', 'http://www.wikidata.org/entity/Q4657162'), ('movieName', 'A Great Coup')]
# [('movie', 'http://www.wikidata.org/entity/Q1540260'), ('movieName', 'A Guide to Recognizing Your Saints')]
# [('movie', 'http://www.wikidata.org/entity/Q14949722'), ('movieName', 'A Gun & a Ring')]
# [('movie', 'http://www.wikidata.org/entity/Q16734496'), ('movieName', 'A Hard Day')]
# [('movie', 'http://www.wikidata.org/entity/Q21029312'), ('movieName', 'A Hen on a Wall')]
# [('movie', 'http://www.wikidata.org/entity/Q2819769'), ('movieName', 'A Hero Never Dies')]
# [('movie', 'http://www.wikidata.org/entity/Q4657559'), ('movieName', 'A Killer Walks')]
# [('movie', 'http://www.wikidata.org/entity/Q4657560'), ('movieName', 'A Killer in the Family')]
# [('movie', 'http://www.wikidata.org/entity/Q39073465'), ('movieName', 'A Killing Affair')]
# [('movie', 'http://www.wikidata.org/entity/Q4468621'), ('movieName', 'A Killing in a Small Town')]
# [('movie', 'http://www.wikidata.org/entity/Q2040561'), ('movieName', 'A Kiss Before Dying')]
# [('movie', 'http://www.wikidata.org/entity/Q3549616'), ('movieName', 'A Kiss for a Killer')]
# [('movie', 'http://www.wikidata.org/entity/Q1056925'), ('movieName', 'A Lady Without Passport')]
# [('movie', 'http://www.wikidata.org/entity/Q112951'), ('movieName', 'A Little Thing Called Murder')]
# [('movie', 'http://www.wikidata.org/entity/Q4657900'), ('movieName', 'A London Flat Mystery')]
# [('movie', 'http://www.wikidata.org/entity/Q4657905'), ('movieName', 'A Lonely Place for Dying')]
# [('movie', 'http://www.wikidata.org/entity/Q3548424'), ('movieName', 'A Loser')]
# [('movie', 'http://www.wikidata.org/entity/Q4657960'), ('movieName', 'A Love')]
# [('movie', 'http://www.wikidata.org/entity/Q1571203'), ('movieName', 'A Lovely Way to Die')]
# [('movie', 'http://www.wikidata.org/entity/Q6082130'), ('movieName', 'A Madonna in Laleli')]
# [('movie', 'http://www.wikidata.org/entity/Q9557913'), ('movieName', 'A Maldição do Sanpaku')]
# [('movie', 'http://www.wikidata.org/entity/Q1385502'), ('movieName', 'A Man Apart')]
# [('movie', 'http://www.wikidata.org/entity/Q3808686'), ('movieName', 'A Man Betrayed')]
# [('movie', 'http://www.wikidata.org/entity/Q3548877'), ('movieName', 'A Man Named Rocca')]
# [('movie', 'http://www.wikidata.org/entity/Q56886899'), ('movieName', 'A Man of Quality')]
# [('movie', 'http://www.wikidata.org/entity/Q18709007'), ('movieName', "A Man's Shadow")]
# [('movie', 'http://www.wikidata.org/entity/Q4658159'), ('movieName', 'A Matter of Murder')]
# [('movie', 'http://www.wikidata.org/entity/Q4658174'), ('movieName', 'A Matter of Wife... And Death')]
# [('movie', 'http://www.wikidata.org/entity/Q22973931'), ('movieName', 'A Mere Life')]
# [('movie', 'http://www.wikidata.org/entity/Q4658250'), ('movieName', 'A Million Colours')]
# [('movie', 'http://www.wikidata.org/entity/Q26243026'), ('movieName', 'A Minute for Murder')]
# [('movie', 'http://www.wikidata.org/entity/Q2819829'), ('movieName', 'A Moment of Romance')]
# [('movie', 'http://www.wikidata.org/entity/Q10940677'), ('movieName', 'A Moment of Romance II')]
# [('movie', 'http://www.wikidata.org/entity/Q15915435'), ('movieName', 'A Most Violent Year')]
# [('movie', 'http://www.wikidata.org/entity/Q2819825'), ('movieName', 'A Most Wanted Man')]
# [('movie', 'http://www.wikidata.org/entity/Q300490'), ('movieName', 'A Murder of Crows')]
# [('movie', 'http://www.wikidata.org/entity/Q18639976'), ('movieName', 'A Murder of Quality')]
# [('movie', 'http://www.wikidata.org/entity/Q12126547'), ('movieName', 'A Night for Crime')]
# [('movie', 'http://www.wikidata.org/entity/Q11325177'), ('movieName', 'A Night in Nude: Salvation')]
# [('movie', 'http://www.wikidata.org/entity/Q15378692'), ('movieName', 'A Night of Adventure')]
# [('movie', 'http://www.wikidata.org/entity/Q25999757'), ('movieName', 'A Passenger Disappeared')]
# [('movie', 'http://www.wikidata.org/entity/Q300517'), ('movieName', 'A Perfect Getaway')]
# [('movie', 'http://www.wikidata.org/entity/Q282069'), ('movieName', 'A Perfect Murder')]
# [('movie', 'http://www.wikidata.org/entity/Q174683'), ('movieName', 'A Perfect World')]
# [('movie', 'http://www.wikidata.org/entity/Q18170261'), ('movieName', 'A Place in the Stars')]
# [('movie', 'http://www.wikidata.org/entity/Q4658896'), ('movieName', 'A Place to Go')]
# [('movie', 'http://www.wikidata.org/entity/Q759383'), ('movieName', 'A Prayer for the Dying')]
# [('movie', 'http://www.wikidata.org/entity/Q3549320'), ('movieName', 'A Private Affair')]
# [('movie', 'http://www.wikidata.org/entity/Q1961769'), ('movieName', 'A Rage in Harlem')]
# [('movie', 'http://www.wikidata.org/entity/Q4659177'), ('movieName', 'A Reasonable Man')]
# [('movie', 'http://www.wikidata.org/entity/Q3602700'), ('movieName', "A Rogue's Romance")]
# [('movie', 'http://www.wikidata.org/entity/Q19818485'), ('movieName', "A Rogue's Wife")]
# [('movie', 'http://www.wikidata.org/entity/Q21528014'), ('movieName', 'A Safe Affair')]
# 200

# %%
#Now I get also the production company from the movies 
queryString = """
SELECT DISTINCT ?movie ?movieName ?company ?companyName
WHERE {
   # bind something
   # ?movie wdt:P136 wd:Q959790.
   # ?movie wdt:P272 ?company. 
   
   # get the label
   # ?movie sc:name ?movieName.
   # ?company sc:name ?companyName .
}
ORDER BY ?companyName
LIMIT 200
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('movie', 'http://www.wikidata.org/entity/Q705232'), ('movieName', 'Arsène Lupin'), ('company', 'http://www.wikidata.org/entity/Q1554656'), ('companyName', '01 Distribution')]
# [('movie', 'http://www.wikidata.org/entity/Q3233538'), ('movieName', 'Rivals'), ('company', 'http://www.wikidata.org/entity/Q13515711'), ('companyName', '13ème Rue Universal')]
# [('movie', 'http://www.wikidata.org/entity/Q2296287'), ('movieName', 'The Chicago Code'), ('company', 'http://www.wikidata.org/entity/Q2717612'), ('companyName', '20th Century Fox Television')]
# [('movie', 'http://www.wikidata.org/entity/Q11510316'), ('movieName', 'Love Under Fire'), ('company', 'http://www.wikidata.org/entity/Q434841'), ('companyName', '20th Century Studios')]
# [('movie', 'http://www.wikidata.org/entity/Q586880'), ('movieName', 'Vanishing Point'), ('company', 'http://www.wikidata.org/entity/Q434841'), ('companyName', '20th Century Studios')]
# [('movie', 'http://www.wikidata.org/entity/Q2533178'), ('movieName', 'Deadline – U.S.A.'), ('company', 'http://www.wikidata.org/entity/Q434841'), ('companyName', '20th Century Studios')]
# [('movie', 'http://www.wikidata.org/entity/Q23780457'), ('movieName', 'Kingsman: The Golden Circle'), ('company', 'http://www.wikidata.org/entity/Q434841'), ('companyName', '20th Century Studios')]
# [('movie', 'http://www.wikidata.org/entity/Q1907536'), ('movieName', 'The Laughing Policeman'), ('company', 'http://www.wikidata.org/entity/Q434841'), ('companyName', '20th Century Studios')]
# [('movie', 'http://www.wikidata.org/entity/Q1146552'), ('movieName', 'Point Break'), ('company', 'http://www.wikidata.org/entity/Q434841'), ('companyName', '20th Century Studios')]
# [('movie', 'http://www.wikidata.org/entity/Q3804043'), ('movieName', "It Shouldn't Happen to a Dog"), ('company', 'http://www.wikidata.org/entity/Q434841'), ('companyName', '20th Century Studios')]
# [('movie', 'http://www.wikidata.org/entity/Q1322784'), ('movieName', 'French Connection II'), ('company', 'http://www.wikidata.org/entity/Q434841'), ('companyName', '20th Century Studios')]
# [('movie', 'http://www.wikidata.org/entity/Q220735'), ('movieName', 'The French Connection'), ('company', 'http://www.wikidata.org/entity/Q434841'), ('companyName', '20th Century Studios')]
# [('movie', 'http://www.wikidata.org/entity/Q3985531'), ('movieName', 'That I May Live'), ('company', 'http://www.wikidata.org/entity/Q434841'), ('companyName', '20th Century Studios')]
# [('movie', 'http://www.wikidata.org/entity/Q1466657'), ('movieName', '9 to 5'), ('company', 'http://www.wikidata.org/entity/Q434841'), ('companyName', '20th Century Studios')]
# [('movie', 'http://www.wikidata.org/entity/Q1165314'), ('movieName', 'Max Payne'), ('company', 'http://www.wikidata.org/entity/Q434841'), ('companyName', '20th Century Studios')]
# [('movie', 'http://www.wikidata.org/entity/Q7248035'), ('movieName', 'Professional Soldier'), ('company', 'http://www.wikidata.org/entity/Q434841'), ('companyName', '20th Century Studios')]
# [('movie', 'http://www.wikidata.org/entity/Q610159'), ('movieName', 'Elektra'), ('company', 'http://www.wikidata.org/entity/Q434841'), ('companyName', '20th Century Studios')]
# [('movie', 'http://www.wikidata.org/entity/Q1122281'), ('movieName', 'The King of Comedy'), ('company', 'http://www.wikidata.org/entity/Q434841'), ('companyName', '20th Century Studios')]
# [('movie', 'http://www.wikidata.org/entity/Q2000941'), ('movieName', 'Kiss of Death'), ('company', 'http://www.wikidata.org/entity/Q434841'), ('companyName', '20th Century Studios')]
# [('movie', 'http://www.wikidata.org/entity/Q1194465'), ('movieName', 'The Hound of the Baskervilles'), ('company', 'http://www.wikidata.org/entity/Q434841'), ('companyName', '20th Century Studios')]
# [('movie', 'http://www.wikidata.org/entity/Q1210852'), ('movieName', 'The Adventures of Sherlock Holmes'), ('company', 'http://www.wikidata.org/entity/Q434841'), ('companyName', '20th Century Studios')]
# [('movie', 'http://www.wikidata.org/entity/Q1398816'), ('movieName', 'Where the Sidewalk Ends'), ('company', 'http://www.wikidata.org/entity/Q434841'), ('companyName', '20th Century Studios')]
# [('movie', 'http://www.wikidata.org/entity/Q1401787'), ('movieName', 'The Dark Corner'), ('company', 'http://www.wikidata.org/entity/Q434841'), ('companyName', '20th Century Studios')]
# [('movie', 'http://www.wikidata.org/entity/Q7766452'), ('movieName', 'The Steel Trap'), ('company', 'http://www.wikidata.org/entity/Q434841'), ('companyName', '20th Century Studios')]
# [('movie', 'http://www.wikidata.org/entity/Q5084675'), ('movieName', 'Charlie Chan in Reno'), ('company', 'http://www.wikidata.org/entity/Q434841'), ('companyName', '20th Century Studios')]
# [('movie', 'http://www.wikidata.org/entity/Q27689100'), ('movieName', 'Murder on the Orient Express'), ('company', 'http://www.wikidata.org/entity/Q434841'), ('companyName', '20th Century Studios')]
# [('movie', 'http://www.wikidata.org/entity/Q1754410'), ('movieName', 'The Chase'), ('company', 'http://www.wikidata.org/entity/Q434841'), ('companyName', '20th Century Studios')]
# [('movie', 'http://www.wikidata.org/entity/Q108006'), ('movieName', 'Speed'), ('company', 'http://www.wikidata.org/entity/Q434841'), ('companyName', '20th Century Studios')]
# [('movie', 'http://www.wikidata.org/entity/Q105993'), ('movieName', 'Die Hard 2'), ('company', 'http://www.wikidata.org/entity/Q434841'), ('companyName', '20th Century Studios')]
# [('movie', 'http://www.wikidata.org/entity/Q3212069'), ('movieName', 'Moontide'), ('company', 'http://www.wikidata.org/entity/Q434841'), ('companyName', '20th Century Studios')]
# [('movie', 'http://www.wikidata.org/entity/Q3213542'), ('movieName', 'Black Widow'), ('company', 'http://www.wikidata.org/entity/Q434841'), ('companyName', '20th Century Studios')]
# [('movie', 'http://www.wikidata.org/entity/Q3232960'), ('movieName', 'Night People'), ('company', 'http://www.wikidata.org/entity/Q434841'), ('companyName', '20th Century Studios')]
# [('movie', 'http://www.wikidata.org/entity/Q860277'), ('movieName', "Charlie Chan's Secret"), ('company', 'http://www.wikidata.org/entity/Q434841'), ('companyName', '20th Century Studios')]
# [('movie', 'http://www.wikidata.org/entity/Q903459'), ('movieName', 'Downtown'), ('company', 'http://www.wikidata.org/entity/Q434841'), ('companyName', '20th Century Studios')]
# [('movie', 'http://www.wikidata.org/entity/Q773645'), ('movieName', "What's the Worst That Could Happen?"), ('company', 'http://www.wikidata.org/entity/Q434841'), ('companyName', '20th Century Studios')]
# [('movie', 'http://www.wikidata.org/entity/Q429408'), ('movieName', 'The Star Chamber'), ('company', 'http://www.wikidata.org/entity/Q434841'), ('companyName', '20th Century Studios')]
# [('movie', 'http://www.wikidata.org/entity/Q301132'), ('movieName', 'Fallen Angel'), ('company', 'http://www.wikidata.org/entity/Q434841'), ('companyName', '20th Century Studios')]
# [('movie', 'http://www.wikidata.org/entity/Q1447056'), ('movieName', 'Mister 880'), ('company', 'http://www.wikidata.org/entity/Q434841'), ('companyName', '20th Century Studios')]
# [('movie', 'http://www.wikidata.org/entity/Q4655525'), ('movieName', 'A Blueprint for Murder'), ('company', 'http://www.wikidata.org/entity/Q434841'), ('companyName', '20th Century Studios')]
# [('movie', 'http://www.wikidata.org/entity/Q7993616'), ('movieName', 'While New York Sleeps'), ('company', 'http://www.wikidata.org/entity/Q434841'), ('companyName', '20th Century Studios')]
# [('movie', 'http://www.wikidata.org/entity/Q14920425'), ('movieName', 'Gone Girl'), ('company', 'http://www.wikidata.org/entity/Q434841'), ('companyName', '20th Century Studios')]
# [('movie', 'http://www.wikidata.org/entity/Q578873'), ('movieName', 'Entrapment'), ('company', 'http://www.wikidata.org/entity/Q434841'), ('companyName', '20th Century Studios')]
# [('movie', 'http://www.wikidata.org/entity/Q39659551'), ('movieName', 'The Hate U Give'), ('company', 'http://www.wikidata.org/entity/Q434841'), ('companyName', '20th Century Studios')]
# [('movie', 'http://www.wikidata.org/entity/Q976149'), ('movieName', 'Laura'), ('company', 'http://www.wikidata.org/entity/Q434841'), ('companyName', '20th Century Studios')]
# [('movie', 'http://www.wikidata.org/entity/Q332348'), ('movieName', 'Wall Street'), ('company', 'http://www.wikidata.org/entity/Q434841'), ('companyName', '20th Century Studios')]
# [('movie', 'http://www.wikidata.org/entity/Q1217573'), ('movieName', 'Rising Sun'), ('company', 'http://www.wikidata.org/entity/Q434841'), ('companyName', '20th Century Studios')]
# [('movie', 'http://www.wikidata.org/entity/Q3815017'), ('movieName', 'Charlie Chan at the Opera'), ('company', 'http://www.wikidata.org/entity/Q434841'), ('companyName', '20th Century Studios')]
# [('movie', 'http://www.wikidata.org/entity/Q3819803'), ('movieName', '15 Maiden Lane'), ('company', 'http://www.wikidata.org/entity/Q434841'), ('companyName', '20th Century Studios')]
# [('movie', 'http://www.wikidata.org/entity/Q3998016'), ('movieName', 'Dangerous Crossing'), ('company', 'http://www.wikidata.org/entity/Q434841'), ('companyName', '20th Century Studios')]
# [('movie', 'http://www.wikidata.org/entity/Q7945266'), ('movieName', 'W.W. and the Dixie Dancekings'), ('company', 'http://www.wikidata.org/entity/Q434841'), ('companyName', '20th Century Studios')]
# [('movie', 'http://www.wikidata.org/entity/Q2419807'), ('movieName', 'Cry of the City'), ('company', 'http://www.wikidata.org/entity/Q434841'), ('companyName', '20th Century Studios')]
# [('movie', 'http://www.wikidata.org/entity/Q685234'), ('movieName', 'Nightmare Alley'), ('company', 'http://www.wikidata.org/entity/Q434841'), ('companyName', '20th Century Studios')]
# [('movie', 'http://www.wikidata.org/entity/Q1139801'), ('movieName', 'Date Night'), ('company', 'http://www.wikidata.org/entity/Q434841'), ('companyName', '20th Century Studios')]
# [('movie', 'http://www.wikidata.org/entity/Q978974'), ('movieName', 'Hoffa'), ('company', 'http://www.wikidata.org/entity/Q434841'), ('companyName', '20th Century Studios')]
# [('movie', 'http://www.wikidata.org/entity/Q15068238'), ('movieName', 'Kingsman: The Secret Service'), ('company', 'http://www.wikidata.org/entity/Q434841'), ('companyName', '20th Century Studios')]
# [('movie', 'http://www.wikidata.org/entity/Q17125184'), ('movieName', 'Strange Triangle'), ('company', 'http://www.wikidata.org/entity/Q434841'), ('companyName', '20th Century Studios')]
# [('movie', 'http://www.wikidata.org/entity/Q3666654'), ('movieName', 'Charlie Chan at the Olympics'), ('company', 'http://www.wikidata.org/entity/Q434841'), ('companyName', '20th Century Studios')]
# [('movie', 'http://www.wikidata.org/entity/Q2325459'), ('movieName', 'S. Darko'), ('company', 'http://www.wikidata.org/entity/Q434841'), ('companyName', '20th Century Studios')]
# [('movie', 'http://www.wikidata.org/entity/Q4880802'), ('movieName', 'Behind Green Lights'), ('company', 'http://www.wikidata.org/entity/Q434841'), ('companyName', '20th Century Studios')]
# [('movie', 'http://www.wikidata.org/entity/Q5866378'), ('movieName', 'The Brasher Doubloon'), ('company', 'http://www.wikidata.org/entity/Q434841'), ('companyName', '20th Century Studios')]
# [('movie', 'http://www.wikidata.org/entity/Q659896'), ('movieName', 'The Boston Strangler'), ('company', 'http://www.wikidata.org/entity/Q434841'), ('companyName', '20th Century Studios')]
# [('movie', 'http://www.wikidata.org/entity/Q1056270'), ('movieName', 'Johnny Apollo'), ('company', 'http://www.wikidata.org/entity/Q434841'), ('companyName', '20th Century Studios')]
# [('movie', 'http://www.wikidata.org/entity/Q2602267'), ('movieName', 'House of Bamboo'), ('company', 'http://www.wikidata.org/entity/Q434841'), ('companyName', '20th Century Studios')]
# [('movie', 'http://www.wikidata.org/entity/Q1259427'), ('movieName', 'The Driver'), ('company', 'http://www.wikidata.org/entity/Q434841'), ('companyName', '20th Century Studios')]
# [('movie', 'http://www.wikidata.org/entity/Q3752169'), ('movieName', 'Whirlpool'), ('company', 'http://www.wikidata.org/entity/Q434841'), ('companyName', '20th Century Studios')]
# [('movie', 'http://www.wikidata.org/entity/Q21527888'), ('movieName', 'My Marriage'), ('company', 'http://www.wikidata.org/entity/Q434841'), ('companyName', '20th Century Studios')]
# [('movie', 'http://www.wikidata.org/entity/Q1463361'), ('movieName', 'Wisdom'), ('company', 'http://www.wikidata.org/entity/Q434841'), ('companyName', '20th Century Studios')]
# [('movie', 'http://www.wikidata.org/entity/Q1625964'), ('movieName', 'Homeboy'), ('company', 'http://www.wikidata.org/entity/Q434841'), ('companyName', '20th Century Studios')]
# [('movie', 'http://www.wikidata.org/entity/Q3235479'), ('movieName', 'Seven Thieves'), ('company', 'http://www.wikidata.org/entity/Q434841'), ('companyName', '20th Century Studios')]
# [('movie', 'http://www.wikidata.org/entity/Q3226392'), ('movieName', 'Bulldog Drummond Strikes Back'), ('company', 'http://www.wikidata.org/entity/Q434841'), ('companyName', '20th Century Studios')]
# [('movie', 'http://www.wikidata.org/entity/Q425904'), ('movieName', 'Night and the City'), ('company', 'http://www.wikidata.org/entity/Q434841'), ('companyName', '20th Century Studios')]
# [('movie', 'http://www.wikidata.org/entity/Q468033'), ('movieName', 'Road to Perdition'), ('company', 'http://www.wikidata.org/entity/Q434841'), ('companyName', '20th Century Studios')]
# [('movie', 'http://www.wikidata.org/entity/Q19874829'), ('movieName', 'Just Off Broadway'), ('company', 'http://www.wikidata.org/entity/Q434841'), ('companyName', '20th Century Studios')]
# [('movie', 'http://www.wikidata.org/entity/Q1106127'), ('movieName', 'The Street with No Name'), ('company', 'http://www.wikidata.org/entity/Q434841'), ('companyName', '20th Century Studios')]
# [('movie', 'http://www.wikidata.org/entity/Q7763422'), ('movieName', 'The Seven-Ups'), ('company', 'http://www.wikidata.org/entity/Q434841'), ('companyName', '20th Century Studios')]
# [('movie', 'http://www.wikidata.org/entity/Q3576935'), ('movieName', '23 Paces to Baker Street'), ('company', 'http://www.wikidata.org/entity/Q434841'), ('companyName', '20th Century Studios')]
# [('movie', 'http://www.wikidata.org/entity/Q1548602'), ('movieName', 'Only the Lonely'), ('company', 'http://www.wikidata.org/entity/Q434841'), ('companyName', '20th Century Studios')]
# [('movie', 'http://www.wikidata.org/entity/Q1757431'), ('movieName', 'The Girl in the Red Velvet Swing'), ('company', 'http://www.wikidata.org/entity/Q434841'), ('companyName', '20th Century Studios')]
# [('movie', 'http://www.wikidata.org/entity/Q1985667'), ('movieName', 'The Grissom Gang'), ('company', 'http://www.wikidata.org/entity/Q434841'), ('companyName', '20th Century Studios')]
# [('movie', 'http://www.wikidata.org/entity/Q1350631'), ('movieName', 'Off Limits'), ('company', 'http://www.wikidata.org/entity/Q434841'), ('companyName', '20th Century Studios')]
# [('movie', 'http://www.wikidata.org/entity/Q3061599'), ('movieName', 'The Counselor'), ('company', 'http://www.wikidata.org/entity/Q434841'), ('companyName', '20th Century Studios')]
# [('movie', 'http://www.wikidata.org/entity/Q3233309'), ('movieName', 'Violent Saturday'), ('company', 'http://www.wikidata.org/entity/Q434841'), ('companyName', '20th Century Studios')]
# [('movie', 'http://www.wikidata.org/entity/Q403830'), ('movieName', 'Less Than Zero'), ('company', 'http://www.wikidata.org/entity/Q434841'), ('companyName', '20th Century Studios')]
# [('movie', 'http://www.wikidata.org/entity/Q2715975'), ('movieName', 'Call Northside 777'), ('company', 'http://www.wikidata.org/entity/Q434841'), ('companyName', '20th Century Studios')]
# [('movie', 'http://www.wikidata.org/entity/Q3460360'), ('movieName', 'This Is My Affair'), ('company', 'http://www.wikidata.org/entity/Q434841'), ('companyName', '20th Century Studios')]
# [('movie', 'http://www.wikidata.org/entity/Q727334'), ('movieName', 'Regeneration'), ('company', 'http://www.wikidata.org/entity/Q434841'), ('companyName', '20th Century Studios')]
# [('movie', 'http://www.wikidata.org/entity/Q1198236'), ('movieName', 'Compulsion'), ('company', 'http://www.wikidata.org/entity/Q434841'), ('companyName', '20th Century Studios')]
# [('movie', 'http://www.wikidata.org/entity/Q1219363'), ('movieName', 'Black Widow'), ('company', 'http://www.wikidata.org/entity/Q434841'), ('companyName', '20th Century Studios')]
# [('movie', 'http://www.wikidata.org/entity/Q1457849'), ('movieName', "Thieves' Highway"), ('company', 'http://www.wikidata.org/entity/Q434841'), ('companyName', '20th Century Studios')]
# [('movie', 'http://www.wikidata.org/entity/Q4491086'), ('movieName', 'Charlie Chan on Broadway'), ('company', 'http://www.wikidata.org/entity/Q434841'), ('companyName', '20th Century Studios')]
# [('movie', 'http://www.wikidata.org/entity/Q514812'), ('movieName', 'Capone'), ('company', 'http://www.wikidata.org/entity/Q434841'), ('companyName', '20th Century Studios')]
# [('movie', 'http://www.wikidata.org/entity/Q1636538'), ('movieName', 'State of Grace'), ('company', 'http://www.wikidata.org/entity/Q434841'), ('companyName', '20th Century Studios')]
# [('movie', 'http://www.wikidata.org/entity/Q81845'), ('movieName', 'Vallanzasca - Angels of Evil'), ('company', 'http://www.wikidata.org/entity/Q434841'), ('companyName', '20th Century Studios')]
# [('movie', 'http://www.wikidata.org/entity/Q54366261'), ('movieName', 'Kin'), ('company', 'http://www.wikidata.org/entity/Q16973462'), ('companyName', '21 Laps Entertainment')]
# [('movie', 'http://www.wikidata.org/entity/Q848297'), ('movieName', 'Death Wish V: The Face of Death'), ('company', 'http://www.wikidata.org/entity/Q4631061'), ('companyName', '21st Century Film Corporation')]
# [('movie', 'http://www.wikidata.org/entity/Q786038'), ('movieName', 'We Own the Night'), ('company', 'http://www.wikidata.org/entity/Q4632862'), ('companyName', '2929 Entertainment')]
# [('movie', 'http://www.wikidata.org/entity/Q288150'), ('movieName', 'Freedom Writers'), ('company', 'http://www.wikidata.org/entity/Q17371413'), ('companyName', '2S Films')]
# [('movie', 'http://www.wikidata.org/entity/Q1402398'), ('movieName', 'Humanité'), ('company', 'http://www.wikidata.org/entity/Q97958214'), ('companyName', '3B Productions')]
# [('movie', 'http://www.wikidata.org/entity/Q81224'), ('movieName', 'Inside Man'), ('company', 'http://www.wikidata.org/entity/Q1138658'), ('companyName', '40 Acres & A Mule Filmworks')]
# [('movie', 'http://www.wikidata.org/entity/Q1529637'), ('movieName', 'Oldboy'), ('company', 'http://www.wikidata.org/entity/Q1138658'), ('companyName', '40 Acres & A Mule Filmworks')]
# [('movie', 'http://www.wikidata.org/entity/Q218458'), ('movieName', '25th Hour'), ('company', 'http://www.wikidata.org/entity/Q1138658'), ('companyName', '40 Acres & A Mule Filmworks')]
# [('movie', 'http://www.wikidata.org/entity/Q2268296'), ('movieName', 'Clockers'), ('company', 'http://www.wikidata.org/entity/Q1138658'), ('companyName', '40 Acres & A Mule Filmworks')]
# [('movie', 'http://www.wikidata.org/entity/Q19885337'), ('movieName', 'Chiraq'), ('company', 'http://www.wikidata.org/entity/Q1138658'), ('companyName', '40 Acres & A Mule Filmworks')]
# [('movie', 'http://www.wikidata.org/entity/Q1150713'), ('movieName', 'Summer of Sam'), ('company', 'http://www.wikidata.org/entity/Q1138658'), ('companyName', '40 Acres & A Mule Filmworks')]
# [('movie', 'http://www.wikidata.org/entity/Q81597'), ('movieName', 'New Jersey Drive'), ('company', 'http://www.wikidata.org/entity/Q1138658'), ('companyName', '40 Acres & A Mule Filmworks')]
# [('movie', 'http://www.wikidata.org/entity/Q950700'), ('movieName', 'From Dusk Till Dawn 2: Texas Blood Money'), ('company', 'http://www.wikidata.org/entity/Q300323'), ('companyName', 'A Band Apart')]
# [('movie', 'http://www.wikidata.org/entity/Q196004'), ('movieName', 'From Dusk till Dawn'), ('company', 'http://www.wikidata.org/entity/Q300323'), ('companyName', 'A Band Apart')]
# [('movie', 'http://www.wikidata.org/entity/Q431252'), ('movieName', 'Jackie Brown'), ('company', 'http://www.wikidata.org/entity/Q300323'), ('companyName', 'A Band Apart')]
# [('movie', 'http://www.wikidata.org/entity/Q55624605'), ('movieName', 'Nancy Drew and the Hidden Staircase'), ('company', 'http://www.wikidata.org/entity/Q59618852'), ('companyName', 'A Very Good Production')]
# [('movie', 'http://www.wikidata.org/entity/Q16154183'), ('movieName', 'And Then There Were None'), ('company', 'http://www.wikidata.org/entity/Q83723'), ('companyName', 'A&E Networks')]
# [('movie', 'http://www.wikidata.org/entity/Q858450'), ('movieName', 'The Mighty Quinn'), ('company', 'http://www.wikidata.org/entity/Q277626'), ('companyName', 'A&M Records')]
# [('movie', 'http://www.wikidata.org/entity/Q204416'), ('movieName', 'Felidae'), ('company', 'http://www.wikidata.org/entity/Q2748878'), ('companyName', 'A. Film A/S')]
# [('movie', 'http://www.wikidata.org/entity/Q16863042'), ('movieName', 'American Crime'), ('company', 'http://www.wikidata.org/entity/Q287218'), ('companyName', 'ABC Signature')]
# [('movie', 'http://www.wikidata.org/entity/Q8060222'), ('movieName', 'Yuddham Sei'), ('company', 'http://www.wikidata.org/entity/Q4651702'), ('companyName', 'AGS Entertainment')]
# [('movie', 'http://www.wikidata.org/entity/Q30641164'), ('movieName', 'McMafia'), ('company', 'http://www.wikidata.org/entity/Q294660'), ('companyName', 'AMC')]
# [('movie', 'http://www.wikidata.org/entity/Q283555'), ('movieName', 'Talaash: The Answer Lies Within'), ('company', 'http://www.wikidata.org/entity/Q2820005'), ('companyName', 'Aamir khan Productions')]
# [('movie', 'http://www.wikidata.org/entity/Q102036246'), ('movieName', 'Drishyam 2'), ('company', 'http://www.wikidata.org/entity/Q4662716'), ('companyName', 'Aashirvad Cinemas')]
# [('movie', 'http://www.wikidata.org/entity/Q15401703'), ('movieName', 'Drishyam'), ('company', 'http://www.wikidata.org/entity/Q4662716'), ('companyName', 'Aashirvad Cinemas')]
# [('movie', 'http://www.wikidata.org/entity/Q7821735'), ('movieName', 'Tony'), ('company', 'http://www.wikidata.org/entity/Q4664352'), ('companyName', 'AbbottVision')]
# [('movie', 'http://www.wikidata.org/entity/Q30607852'), ('movieName', 'Keshava'), ('company', 'http://www.wikidata.org/entity/Q27958422'), ('companyName', 'Abhishek Pictures')]
# [('movie', 'http://www.wikidata.org/entity/Q16154183'), ('movieName', 'And Then There Were None'), ('company', 'http://www.wikidata.org/entity/Q4674554'), ('companyName', 'Acorn Media UK')]
# [('movie', 'http://www.wikidata.org/entity/Q27058562'), ('movieName', 'Der Athen Krimi - Trojanische Pferde'), ('company', 'http://www.wikidata.org/entity/Q266276'), ('companyName', 'Action Concept')]
# [('movie', 'http://www.wikidata.org/entity/Q12125409'), ('movieName', 'Kitty and the Bagman'), ('company', 'http://www.wikidata.org/entity/Q4680387'), ('companyName', 'Adams Packer Film Productions')]
# [('movie', 'http://www.wikidata.org/entity/Q1513821'), ('movieName', "For a Cop's Hide"), ('company', 'http://www.wikidata.org/entity/Q2399565'), ('companyName', 'Adel Productions')]
# [('movie', 'http://www.wikidata.org/entity/Q839294'), ('movieName', 'Death of a Corrupt Man'), ('company', 'http://www.wikidata.org/entity/Q2399565'), ('companyName', 'Adel Productions')]
# [('movie', 'http://www.wikidata.org/entity/Q3176410'), ('movieName', 'Jeff'), ('company', 'http://www.wikidata.org/entity/Q2399565'), ('companyName', 'Adel Productions')]
# [('movie', 'http://www.wikidata.org/entity/Q894172'), ('movieName', 'Borsalino'), ('company', 'http://www.wikidata.org/entity/Q2399565'), ('companyName', 'Adel Productions')]
# [('movie', 'http://www.wikidata.org/entity/Q1340986'), ('movieName', 'Two Men in Town'), ('company', 'http://www.wikidata.org/entity/Q2399565'), ('companyName', 'Adel Productions')]
# [('movie', 'http://www.wikidata.org/entity/Q5351351'), ('movieName', 'El Gringo'), ('company', 'http://www.wikidata.org/entity/Q4690493'), ('companyName', 'After Dark Films')]
# [('movie', 'http://www.wikidata.org/entity/Q135230'), ('movieName', 'Bullet to the Head'), ('company', 'http://www.wikidata.org/entity/Q4690493'), ('companyName', 'After Dark Films')]
# [('movie', 'http://www.wikidata.org/entity/Q1443738'), ('movieName', 'Roberto Succo'), ('company', 'http://www.wikidata.org/entity/Q20724296'), ('companyName', 'Agat Films & Cie - Ex Nihilo')]
# [('movie', 'http://www.wikidata.org/entity/Q2025754'), ('movieName', 'Stolen'), ('company', 'http://www.wikidata.org/entity/Q17081246'), ('companyName', 'Alchemy')]
# [('movie', 'http://www.wikidata.org/entity/Q200827'), ('movieName', 'The Wicker Man'), ('company', 'http://www.wikidata.org/entity/Q4713342'), ('companyName', 'Alcon Entertainment')]
# [('movie', 'http://www.wikidata.org/entity/Q169000'), ('movieName', '16 Blocks'), ('company', 'http://www.wikidata.org/entity/Q4713342'), ('companyName', 'Alcon Entertainment')]
# [('movie', 'http://www.wikidata.org/entity/Q429969'), ('movieName', 'Insomnia'), ('company', 'http://www.wikidata.org/entity/Q4713342'), ('companyName', 'Alcon Entertainment')]
# [('movie', 'http://www.wikidata.org/entity/Q3404003'), ('movieName', 'Prisoners'), ('company', 'http://www.wikidata.org/entity/Q4713342'), ('companyName', 'Alcon Entertainment')]
# [('movie', 'http://www.wikidata.org/entity/Q47703'), ('movieName', 'The Godfather'), ('company', 'http://www.wikidata.org/entity/Q17305146'), ('companyName', 'Alfran Productions')]
# [('movie', 'http://www.wikidata.org/entity/Q467181'), ('movieName', 'The Good Thief'), ('company', 'http://www.wikidata.org/entity/Q10748653'), ('companyName', 'Alliance Atlantis')]
# [('movie', 'http://www.wikidata.org/entity/Q2747218'), ('movieName', 'Victim'), ('company', 'http://www.wikidata.org/entity/Q4732568'), ('companyName', 'Allied Film Makers')]
# [('movie', 'http://www.wikidata.org/entity/Q482632'), ('movieName', 'Séance on a Wet Afternoon'), ('company', 'http://www.wikidata.org/entity/Q4732568'), ('companyName', 'Allied Film Makers')]
# [('movie', 'http://www.wikidata.org/entity/Q1719141'), ('movieName', 'Sweet Sixteen'), ('company', 'http://www.wikidata.org/entity/Q107009153'), ('companyName', 'Alta Films')]
# [('movie', 'http://www.wikidata.org/entity/Q208108'), ('movieName', 'Catch Me If You Can'), ('company', 'http://www.wikidata.org/entity/Q457893'), ('companyName', 'Amblin Entertainment')]
# [('movie', 'http://www.wikidata.org/entity/Q501995'), ('movieName', 'Cape Fear'), ('company', 'http://www.wikidata.org/entity/Q457893'), ('companyName', 'Amblin Entertainment')]
# [('movie', 'http://www.wikidata.org/entity/Q460664'), ('movieName', "Prizzi's Honor"), ('company', 'http://www.wikidata.org/entity/Q169889'), ('companyName', 'American Broadcasting Company')]
# [('movie', 'http://www.wikidata.org/entity/Q3521099'), ('movieName', 'The Grand Budapest Hotel'), ('company', 'http://www.wikidata.org/entity/Q3614056'), ('companyName', 'American Empirical Pictures')]
# [('movie', 'http://www.wikidata.org/entity/Q2663393'), ('movieName', 'Rolling Thunder'), ('company', 'http://www.wikidata.org/entity/Q465224'), ('companyName', 'American International Pictures')]
# [('movie', 'http://www.wikidata.org/entity/Q81995'), ('movieName', 'Dillinger'), ('company', 'http://www.wikidata.org/entity/Q465224'), ('companyName', 'American International Pictures')]
# [('movie', 'http://www.wikidata.org/entity/Q1212396'), ('movieName', 'Boxcar Bertha'), ('company', 'http://www.wikidata.org/entity/Q465224'), ('companyName', 'American International Pictures')]
# [('movie', 'http://www.wikidata.org/entity/Q7719130'), ('movieName', 'The Bonnie Parker Story'), ('company', 'http://www.wikidata.org/entity/Q465224'), ('companyName', 'American International Pictures')]
# [('movie', 'http://www.wikidata.org/entity/Q3224744'), ('movieName', 'The Black Monocle'), ('company', 'http://www.wikidata.org/entity/Q465224'), ('companyName', 'American International Pictures')]
# [('movie', 'http://www.wikidata.org/entity/Q1626875'), ('movieName', 'The Honeymoon Killers'), ('company', 'http://www.wikidata.org/entity/Q465224'), ('companyName', 'American International Pictures')]
# [('movie', 'http://www.wikidata.org/entity/Q4004029'), ('movieName', 'A Bullet for Pretty Boy'), ('company', 'http://www.wikidata.org/entity/Q465224'), ('companyName', 'American International Pictures')]
# [('movie', 'http://www.wikidata.org/entity/Q1119583'), ('movieName', 'Machine-Gun Kelly'), ('company', 'http://www.wikidata.org/entity/Q465224'), ('companyName', 'American International Pictures')]
# [('movie', 'http://www.wikidata.org/entity/Q5706688'), ('movieName', 'Hell Up in Harlem'), ('company', 'http://www.wikidata.org/entity/Q465224'), ('companyName', 'American International Pictures')]
# [('movie', 'http://www.wikidata.org/entity/Q2020244'), ('movieName', 'Swamp Women'), ('company', 'http://www.wikidata.org/entity/Q465224'), ('companyName', 'American International Pictures')]
# [('movie', 'http://www.wikidata.org/entity/Q2905338'), ('movieName', 'Black Caesar'), ('company', 'http://www.wikidata.org/entity/Q465224'), ('companyName', 'American International Pictures')]
# [('movie', 'http://www.wikidata.org/entity/Q1573923'), ('movieName', 'Hammett'), ('company', 'http://www.wikidata.org/entity/Q467348'), ('companyName', 'American Zoetrope')]
# [('movie', 'http://www.wikidata.org/entity/Q1617794'), ('movieName', "Tough Guys Don't Dance"), ('company', 'http://www.wikidata.org/entity/Q467348'), ('companyName', 'American Zoetrope')]
# [('movie', 'http://www.wikidata.org/entity/Q202326'), ('movieName', 'The Godfather Part III'), ('company', 'http://www.wikidata.org/entity/Q467348'), ('companyName', 'American Zoetrope')]
# [('movie', 'http://www.wikidata.org/entity/Q3077738'), ('movieName', 'The Bling Ring'), ('company', 'http://www.wikidata.org/entity/Q467348'), ('companyName', 'American Zoetrope')]
# [('movie', 'http://www.wikidata.org/entity/Q1009788'), ('movieName', 'The Conversation'), ('company', 'http://www.wikidata.org/entity/Q467348'), ('companyName', 'American Zoetrope')]
# [('movie', 'http://www.wikidata.org/entity/Q785351'), ('movieName', 'The Rainmaker'), ('company', 'http://www.wikidata.org/entity/Q467348'), ('companyName', 'American Zoetrope')]
# [('movie', 'http://www.wikidata.org/entity/Q639387'), ('movieName', 'The Cotton Club'), ('company', 'http://www.wikidata.org/entity/Q467348'), ('companyName', 'American Zoetrope')]
# [('movie', 'http://www.wikidata.org/entity/Q786562'), ('movieName', 'The Good Shepherd'), ('company', 'http://www.wikidata.org/entity/Q467348'), ('companyName', 'American Zoetrope')]
# [('movie', 'http://www.wikidata.org/entity/Q3842359'), ('movieName', 'Madhouse'), ('company', 'http://www.wikidata.org/entity/Q470851'), ('companyName', 'Amicus Productions')]
# [('movie', 'http://www.wikidata.org/entity/Q3423295'), ('movieName', 'The Psychopath'), ('company', 'http://www.wikidata.org/entity/Q470851'), ('companyName', 'Amicus Productions')]
# [('movie', 'http://www.wikidata.org/entity/Q1218827'), ('movieName', 'Scream and Scream Again'), ('company', 'http://www.wikidata.org/entity/Q470851'), ('companyName', 'Amicus Productions')]
# [('movie', 'http://www.wikidata.org/entity/Q5433024'), ('movieName', 'Family'), ('company', 'http://www.wikidata.org/entity/Q4746909'), ('companyName', 'Amitabh Bachchan Corporation')]
# [('movie', 'http://www.wikidata.org/entity/Q13472766'), ('movieName', 'Pawn Shop Chronicles'), ('company', 'http://www.wikidata.org/entity/Q4752661'), ('companyName', 'Anchor Bay Entertainment')]
# [('movie', 'http://www.wikidata.org/entity/Q4927639'), ('movieName', 'Blood Money'), ('company', 'http://www.wikidata.org/entity/Q4763633'), ('companyName', 'Anglo-Hollandia')]
# [('movie', 'http://www.wikidata.org/entity/Q2667056'), ('movieName', "John Heriot's Wife"), ('company', 'http://www.wikidata.org/entity/Q4763633'), ('companyName', 'Anglo-Hollandia')]
# [('movie', 'http://www.wikidata.org/entity/Q27965056'), ('movieName', 'Detroit'), ('company', 'http://www.wikidata.org/entity/Q16242963'), ('companyName', 'Annapurna Pictures')]
# [('movie', 'http://www.wikidata.org/entity/Q253901'), ('movieName', 'Lawless'), ('company', 'http://www.wikidata.org/entity/Q16242963'), ('companyName', 'Annapurna Pictures')]
# [('movie', 'http://www.wikidata.org/entity/Q234789'), ('movieName', '44 Inch Chest'), ('company', 'http://www.wikidata.org/entity/Q567633'), ('companyName', 'Anonymous Content')]
# [('movie', 'http://www.wikidata.org/entity/Q301049'), ('movieName', "Winter's Bone"), ('company', 'http://www.wikidata.org/entity/Q567633'), ('companyName', 'Anonymous Content')]
# [('movie', 'http://www.wikidata.org/entity/Q1113039'), ('movieName', 'The Dancer Upstairs'), ('company', 'http://www.wikidata.org/entity/Q571833'), ('companyName', 'Antena 3')]
# [('movie', 'http://www.wikidata.org/entity/Q13823993'), ('movieName', 'The Gunman'), ('company', 'http://www.wikidata.org/entity/Q19600200'), ('companyName', 'Anton Capital Entertainment')]
# [('movie', 'http://www.wikidata.org/entity/Q17182571'), ('movieName', 'Legend'), ('company', 'http://www.wikidata.org/entity/Q19600200'), ('companyName', 'Anton Capital Entertainment')]
# [('movie', 'http://www.wikidata.org/entity/Q485610'), ('movieName', 'Pineapple Express'), ('company', 'http://www.wikidata.org/entity/Q618091'), ('companyName', 'Apatow Productions')]
# [('movie', 'http://www.wikidata.org/entity/Q7379900'), ('movieName', 'Runner, Runner'), ('company', 'http://www.wikidata.org/entity/Q189417'), ('companyName', 'Appian Way')]
# [('movie', 'http://www.wikidata.org/entity/Q6462546'), ('movieName', 'La Flor de la mafia'), ('company', 'http://www.wikidata.org/entity/Q8204054'), ('companyName', 'Argentina Sono Film S.A.C.I.')]
# [('movie', 'http://www.wikidata.org/entity/Q5352062'), ('movieName', 'El Rufián'), ('company', 'http://www.wikidata.org/entity/Q8204054'), ('companyName', 'Argentina Sono Film S.A.C.I.')]
# [('movie', 'http://www.wikidata.org/entity/Q228937'), ('movieName', 'Au Hasard Balthazar'), ('company', 'http://www.wikidata.org/entity/Q2861044'), ('companyName', 'Argos Films')]
# [('movie', 'http://www.wikidata.org/entity/Q610159'), ('movieName', 'Elektra'), ('company', 'http://www.wikidata.org/entity/Q697131'), ('companyName', 'Arnon Milchan')]
# [('movie', 'http://www.wikidata.org/entity/Q562135'), ('movieName', 'Like a Dragon'), ('company', 'http://www.wikidata.org/entity/Q11285667'), ('companyName', 'Art Port')]
# [('movie', 'http://www.wikidata.org/entity/Q1171442'), ('movieName', 'The Silence'), ('company', 'http://www.wikidata.org/entity/Q8073'), ('companyName', 'Arte')]
# [('movie', 'http://www.wikidata.org/entity/Q1402398'), ('movieName', 'Humanité'), ('company', 'http://www.wikidata.org/entity/Q2864822'), ('companyName', 'Arte France Cinéma')]
# [('movie', 'http://www.wikidata.org/entity/Q309459'), ('movieName', 'Paradise Now'), ('company', 'http://www.wikidata.org/entity/Q2864822'), ('companyName', 'Arte France Cinéma')]
# [('movie', 'http://www.wikidata.org/entity/Q909802'), ('movieName', 'The Punisher'), ('company', 'http://www.wikidata.org/entity/Q2865801'), ('companyName', 'Artisan Entertainment')]
# [('movie', 'http://www.wikidata.org/entity/Q1153794'), ('movieName', 'The Punisher'), ('company', 'http://www.wikidata.org/entity/Q2865801'), ('companyName', 'Artisan Entertainment')]
# [('movie', 'http://www.wikidata.org/entity/Q676928'), ('movieName', 'Light Sleeper'), ('company', 'http://www.wikidata.org/entity/Q2865801'), ('companyName', 'Artisan Entertainment')]
# [('movie', 'http://www.wikidata.org/entity/Q7482726'), ('movieName', 'Dreams for Sale'), ('company', 'http://www.wikidata.org/entity/Q798642'), ('companyName', 'Asmik Ace Entertainment')]
# [('movie', 'http://www.wikidata.org/entity/Q3486390'), ('movieName', 'Black Limelight'), ('company', 'http://www.wikidata.org/entity/Q200976'), ('companyName', 'Associated British Picture Corporation')]
# [('movie', 'http://www.wikidata.org/entity/Q960785'), ('movieName', 'Brighton Rock'), ('company', 'http://www.wikidata.org/entity/Q200976'), ('companyName', 'Associated British Picture Corporation')]
# [('movie', 'http://www.wikidata.org/entity/Q1152044'), ('movieName', 'Murder!'), ('company', 'http://www.wikidata.org/entity/Q200976'), ('companyName', 'Associated British Picture Corporation')]
# [('movie', 'http://www.wikidata.org/entity/Q3414563'), ('movieName', 'Cairo Road'), ('company', 'http://www.wikidata.org/entity/Q200976'), ('companyName', 'Associated British Picture Corporation')]
# [('movie', 'http://www.wikidata.org/entity/Q7045122'), ('movieName', 'No Trees in the Street'), ('company', 'http://www.wikidata.org/entity/Q200976'), ('companyName', 'Associated British Picture Corporation')]
# [('movie', 'http://www.wikidata.org/entity/Q6937759'), ('movieName', 'Murder in Soho'), ('company', 'http://www.wikidata.org/entity/Q200976'), ('companyName', 'Associated British Picture Corporation')]
# [('movie', 'http://www.wikidata.org/entity/Q6937689'), ('movieName', 'Murder Without Crime'), ('company', 'http://www.wikidata.org/entity/Q200976'), ('companyName', 'Associated British Picture Corporation')]
# [('movie', 'http://www.wikidata.org/entity/Q7232265'), ('movieName', 'Portrait of Clare'), ('company', 'http://www.wikidata.org/entity/Q200976'), ('companyName', 'Associated British Picture Corporation')]
# 200

# %%
#Now I show only the companies that are instance of Television production company and film production company. 
queryString = """
SELECT DISTINCT ?movie ?movieName ?company ?companyName
WHERE {
   # bind something
   # ?movie wdt:P136 wd:Q959790.
   # ?movie wdt:P272 ?company. 
   # ?company wdt:P31 ?type .
            #Television production company    #film production company 
   VALUES ?type {wd:Q10689397                    wd:Q1762059}
   # get the label
   # ?movie sc:name ?movieName.
   # ?company sc:name ?companyName .
}
ORDER BY ?companyName
LIMIT 200
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('movie', 'http://www.wikidata.org/entity/Q2296287'), ('movieName', 'The Chicago Code'), ('company', 'http://www.wikidata.org/entity/Q2717612'), ('companyName', '20th Century Fox Television')]
# [('movie', 'http://www.wikidata.org/entity/Q11510316'), ('movieName', 'Love Under Fire'), ('company', 'http://www.wikidata.org/entity/Q434841'), ('companyName', '20th Century Studios')]
# [('movie', 'http://www.wikidata.org/entity/Q586880'), ('movieName', 'Vanishing Point'), ('company', 'http://www.wikidata.org/entity/Q434841'), ('companyName', '20th Century Studios')]
# [('movie', 'http://www.wikidata.org/entity/Q2533178'), ('movieName', 'Deadline – U.S.A.'), ('company', 'http://www.wikidata.org/entity/Q434841'), ('companyName', '20th Century Studios')]
# [('movie', 'http://www.wikidata.org/entity/Q23780457'), ('movieName', 'Kingsman: The Golden Circle'), ('company', 'http://www.wikidata.org/entity/Q434841'), ('companyName', '20th Century Studios')]
# [('movie', 'http://www.wikidata.org/entity/Q1907536'), ('movieName', 'The Laughing Policeman'), ('company', 'http://www.wikidata.org/entity/Q434841'), ('companyName', '20th Century Studios')]
# [('movie', 'http://www.wikidata.org/entity/Q1146552'), ('movieName', 'Point Break'), ('company', 'http://www.wikidata.org/entity/Q434841'), ('companyName', '20th Century Studios')]
# [('movie', 'http://www.wikidata.org/entity/Q3804043'), ('movieName', "It Shouldn't Happen to a Dog"), ('company', 'http://www.wikidata.org/entity/Q434841'), ('companyName', '20th Century Studios')]
# [('movie', 'http://www.wikidata.org/entity/Q1322784'), ('movieName', 'French Connection II'), ('company', 'http://www.wikidata.org/entity/Q434841'), ('companyName', '20th Century Studios')]
# [('movie', 'http://www.wikidata.org/entity/Q220735'), ('movieName', 'The French Connection'), ('company', 'http://www.wikidata.org/entity/Q434841'), ('companyName', '20th Century Studios')]
# [('movie', 'http://www.wikidata.org/entity/Q3985531'), ('movieName', 'That I May Live'), ('company', 'http://www.wikidata.org/entity/Q434841'), ('companyName', '20th Century Studios')]
# [('movie', 'http://www.wikidata.org/entity/Q1466657'), ('movieName', '9 to 5'), ('company', 'http://www.wikidata.org/entity/Q434841'), ('companyName', '20th Century Studios')]
# [('movie', 'http://www.wikidata.org/entity/Q1165314'), ('movieName', 'Max Payne'), ('company', 'http://www.wikidata.org/entity/Q434841'), ('companyName', '20th Century Studios')]
# [('movie', 'http://www.wikidata.org/entity/Q7248035'), ('movieName', 'Professional Soldier'), ('company', 'http://www.wikidata.org/entity/Q434841'), ('companyName', '20th Century Studios')]
# [('movie', 'http://www.wikidata.org/entity/Q610159'), ('movieName', 'Elektra'), ('company', 'http://www.wikidata.org/entity/Q434841'), ('companyName', '20th Century Studios')]
# [('movie', 'http://www.wikidata.org/entity/Q1122281'), ('movieName', 'The King of Comedy'), ('company', 'http://www.wikidata.org/entity/Q434841'), ('companyName', '20th Century Studios')]
# [('movie', 'http://www.wikidata.org/entity/Q2000941'), ('movieName', 'Kiss of Death'), ('company', 'http://www.wikidata.org/entity/Q434841'), ('companyName', '20th Century Studios')]
# [('movie', 'http://www.wikidata.org/entity/Q1194465'), ('movieName', 'The Hound of the Baskervilles'), ('company', 'http://www.wikidata.org/entity/Q434841'), ('companyName', '20th Century Studios')]
# [('movie', 'http://www.wikidata.org/entity/Q1210852'), ('movieName', 'The Adventures of Sherlock Holmes'), ('company', 'http://www.wikidata.org/entity/Q434841'), ('companyName', '20th Century Studios')]
# [('movie', 'http://www.wikidata.org/entity/Q1398816'), ('movieName', 'Where the Sidewalk Ends'), ('company', 'http://www.wikidata.org/entity/Q434841'), ('companyName', '20th Century Studios')]
# [('movie', 'http://www.wikidata.org/entity/Q1401787'), ('movieName', 'The Dark Corner'), ('company', 'http://www.wikidata.org/entity/Q434841'), ('companyName', '20th Century Studios')]
# [('movie', 'http://www.wikidata.org/entity/Q7766452'), ('movieName', 'The Steel Trap'), ('company', 'http://www.wikidata.org/entity/Q434841'), ('companyName', '20th Century Studios')]
# [('movie', 'http://www.wikidata.org/entity/Q5084675'), ('movieName', 'Charlie Chan in Reno'), ('company', 'http://www.wikidata.org/entity/Q434841'), ('companyName', '20th Century Studios')]
# [('movie', 'http://www.wikidata.org/entity/Q27689100'), ('movieName', 'Murder on the Orient Express'), ('company', 'http://www.wikidata.org/entity/Q434841'), ('companyName', '20th Century Studios')]
# [('movie', 'http://www.wikidata.org/entity/Q1754410'), ('movieName', 'The Chase'), ('company', 'http://www.wikidata.org/entity/Q434841'), ('companyName', '20th Century Studios')]
# [('movie', 'http://www.wikidata.org/entity/Q108006'), ('movieName', 'Speed'), ('company', 'http://www.wikidata.org/entity/Q434841'), ('companyName', '20th Century Studios')]
# [('movie', 'http://www.wikidata.org/entity/Q105993'), ('movieName', 'Die Hard 2'), ('company', 'http://www.wikidata.org/entity/Q434841'), ('companyName', '20th Century Studios')]
# [('movie', 'http://www.wikidata.org/entity/Q3212069'), ('movieName', 'Moontide'), ('company', 'http://www.wikidata.org/entity/Q434841'), ('companyName', '20th Century Studios')]
# [('movie', 'http://www.wikidata.org/entity/Q3213542'), ('movieName', 'Black Widow'), ('company', 'http://www.wikidata.org/entity/Q434841'), ('companyName', '20th Century Studios')]
# [('movie', 'http://www.wikidata.org/entity/Q3232960'), ('movieName', 'Night People'), ('company', 'http://www.wikidata.org/entity/Q434841'), ('companyName', '20th Century Studios')]
# [('movie', 'http://www.wikidata.org/entity/Q860277'), ('movieName', "Charlie Chan's Secret"), ('company', 'http://www.wikidata.org/entity/Q434841'), ('companyName', '20th Century Studios')]
# [('movie', 'http://www.wikidata.org/entity/Q903459'), ('movieName', 'Downtown'), ('company', 'http://www.wikidata.org/entity/Q434841'), ('companyName', '20th Century Studios')]
# [('movie', 'http://www.wikidata.org/entity/Q773645'), ('movieName', "What's the Worst That Could Happen?"), ('company', 'http://www.wikidata.org/entity/Q434841'), ('companyName', '20th Century Studios')]
# [('movie', 'http://www.wikidata.org/entity/Q429408'), ('movieName', 'The Star Chamber'), ('company', 'http://www.wikidata.org/entity/Q434841'), ('companyName', '20th Century Studios')]
# [('movie', 'http://www.wikidata.org/entity/Q301132'), ('movieName', 'Fallen Angel'), ('company', 'http://www.wikidata.org/entity/Q434841'), ('companyName', '20th Century Studios')]
# [('movie', 'http://www.wikidata.org/entity/Q1447056'), ('movieName', 'Mister 880'), ('company', 'http://www.wikidata.org/entity/Q434841'), ('companyName', '20th Century Studios')]
# [('movie', 'http://www.wikidata.org/entity/Q4655525'), ('movieName', 'A Blueprint for Murder'), ('company', 'http://www.wikidata.org/entity/Q434841'), ('companyName', '20th Century Studios')]
# [('movie', 'http://www.wikidata.org/entity/Q7993616'), ('movieName', 'While New York Sleeps'), ('company', 'http://www.wikidata.org/entity/Q434841'), ('companyName', '20th Century Studios')]
# [('movie', 'http://www.wikidata.org/entity/Q14920425'), ('movieName', 'Gone Girl'), ('company', 'http://www.wikidata.org/entity/Q434841'), ('companyName', '20th Century Studios')]
# [('movie', 'http://www.wikidata.org/entity/Q578873'), ('movieName', 'Entrapment'), ('company', 'http://www.wikidata.org/entity/Q434841'), ('companyName', '20th Century Studios')]
# [('movie', 'http://www.wikidata.org/entity/Q39659551'), ('movieName', 'The Hate U Give'), ('company', 'http://www.wikidata.org/entity/Q434841'), ('companyName', '20th Century Studios')]
# [('movie', 'http://www.wikidata.org/entity/Q976149'), ('movieName', 'Laura'), ('company', 'http://www.wikidata.org/entity/Q434841'), ('companyName', '20th Century Studios')]
# [('movie', 'http://www.wikidata.org/entity/Q332348'), ('movieName', 'Wall Street'), ('company', 'http://www.wikidata.org/entity/Q434841'), ('companyName', '20th Century Studios')]
# [('movie', 'http://www.wikidata.org/entity/Q1217573'), ('movieName', 'Rising Sun'), ('company', 'http://www.wikidata.org/entity/Q434841'), ('companyName', '20th Century Studios')]
# [('movie', 'http://www.wikidata.org/entity/Q3815017'), ('movieName', 'Charlie Chan at the Opera'), ('company', 'http://www.wikidata.org/entity/Q434841'), ('companyName', '20th Century Studios')]
# [('movie', 'http://www.wikidata.org/entity/Q3819803'), ('movieName', '15 Maiden Lane'), ('company', 'http://www.wikidata.org/entity/Q434841'), ('companyName', '20th Century Studios')]
# [('movie', 'http://www.wikidata.org/entity/Q3998016'), ('movieName', 'Dangerous Crossing'), ('company', 'http://www.wikidata.org/entity/Q434841'), ('companyName', '20th Century Studios')]
# [('movie', 'http://www.wikidata.org/entity/Q7945266'), ('movieName', 'W.W. and the Dixie Dancekings'), ('company', 'http://www.wikidata.org/entity/Q434841'), ('companyName', '20th Century Studios')]
# [('movie', 'http://www.wikidata.org/entity/Q2419807'), ('movieName', 'Cry of the City'), ('company', 'http://www.wikidata.org/entity/Q434841'), ('companyName', '20th Century Studios')]
# [('movie', 'http://www.wikidata.org/entity/Q685234'), ('movieName', 'Nightmare Alley'), ('company', 'http://www.wikidata.org/entity/Q434841'), ('companyName', '20th Century Studios')]
# [('movie', 'http://www.wikidata.org/entity/Q1139801'), ('movieName', 'Date Night'), ('company', 'http://www.wikidata.org/entity/Q434841'), ('companyName', '20th Century Studios')]
# [('movie', 'http://www.wikidata.org/entity/Q978974'), ('movieName', 'Hoffa'), ('company', 'http://www.wikidata.org/entity/Q434841'), ('companyName', '20th Century Studios')]
# [('movie', 'http://www.wikidata.org/entity/Q15068238'), ('movieName', 'Kingsman: The Secret Service'), ('company', 'http://www.wikidata.org/entity/Q434841'), ('companyName', '20th Century Studios')]
# [('movie', 'http://www.wikidata.org/entity/Q17125184'), ('movieName', 'Strange Triangle'), ('company', 'http://www.wikidata.org/entity/Q434841'), ('companyName', '20th Century Studios')]
# [('movie', 'http://www.wikidata.org/entity/Q3666654'), ('movieName', 'Charlie Chan at the Olympics'), ('company', 'http://www.wikidata.org/entity/Q434841'), ('companyName', '20th Century Studios')]
# [('movie', 'http://www.wikidata.org/entity/Q2325459'), ('movieName', 'S. Darko'), ('company', 'http://www.wikidata.org/entity/Q434841'), ('companyName', '20th Century Studios')]
# [('movie', 'http://www.wikidata.org/entity/Q4880802'), ('movieName', 'Behind Green Lights'), ('company', 'http://www.wikidata.org/entity/Q434841'), ('companyName', '20th Century Studios')]
# [('movie', 'http://www.wikidata.org/entity/Q5866378'), ('movieName', 'The Brasher Doubloon'), ('company', 'http://www.wikidata.org/entity/Q434841'), ('companyName', '20th Century Studios')]
# [('movie', 'http://www.wikidata.org/entity/Q659896'), ('movieName', 'The Boston Strangler'), ('company', 'http://www.wikidata.org/entity/Q434841'), ('companyName', '20th Century Studios')]
# [('movie', 'http://www.wikidata.org/entity/Q1056270'), ('movieName', 'Johnny Apollo'), ('company', 'http://www.wikidata.org/entity/Q434841'), ('companyName', '20th Century Studios')]
# [('movie', 'http://www.wikidata.org/entity/Q2602267'), ('movieName', 'House of Bamboo'), ('company', 'http://www.wikidata.org/entity/Q434841'), ('companyName', '20th Century Studios')]
# [('movie', 'http://www.wikidata.org/entity/Q1259427'), ('movieName', 'The Driver'), ('company', 'http://www.wikidata.org/entity/Q434841'), ('companyName', '20th Century Studios')]
# [('movie', 'http://www.wikidata.org/entity/Q3752169'), ('movieName', 'Whirlpool'), ('company', 'http://www.wikidata.org/entity/Q434841'), ('companyName', '20th Century Studios')]
# [('movie', 'http://www.wikidata.org/entity/Q21527888'), ('movieName', 'My Marriage'), ('company', 'http://www.wikidata.org/entity/Q434841'), ('companyName', '20th Century Studios')]
# [('movie', 'http://www.wikidata.org/entity/Q1463361'), ('movieName', 'Wisdom'), ('company', 'http://www.wikidata.org/entity/Q434841'), ('companyName', '20th Century Studios')]
# [('movie', 'http://www.wikidata.org/entity/Q1625964'), ('movieName', 'Homeboy'), ('company', 'http://www.wikidata.org/entity/Q434841'), ('companyName', '20th Century Studios')]
# [('movie', 'http://www.wikidata.org/entity/Q3235479'), ('movieName', 'Seven Thieves'), ('company', 'http://www.wikidata.org/entity/Q434841'), ('companyName', '20th Century Studios')]
# [('movie', 'http://www.wikidata.org/entity/Q3226392'), ('movieName', 'Bulldog Drummond Strikes Back'), ('company', 'http://www.wikidata.org/entity/Q434841'), ('companyName', '20th Century Studios')]
# [('movie', 'http://www.wikidata.org/entity/Q425904'), ('movieName', 'Night and the City'), ('company', 'http://www.wikidata.org/entity/Q434841'), ('companyName', '20th Century Studios')]
# [('movie', 'http://www.wikidata.org/entity/Q468033'), ('movieName', 'Road to Perdition'), ('company', 'http://www.wikidata.org/entity/Q434841'), ('companyName', '20th Century Studios')]
# [('movie', 'http://www.wikidata.org/entity/Q19874829'), ('movieName', 'Just Off Broadway'), ('company', 'http://www.wikidata.org/entity/Q434841'), ('companyName', '20th Century Studios')]
# [('movie', 'http://www.wikidata.org/entity/Q1106127'), ('movieName', 'The Street with No Name'), ('company', 'http://www.wikidata.org/entity/Q434841'), ('companyName', '20th Century Studios')]
# [('movie', 'http://www.wikidata.org/entity/Q7763422'), ('movieName', 'The Seven-Ups'), ('company', 'http://www.wikidata.org/entity/Q434841'), ('companyName', '20th Century Studios')]
# [('movie', 'http://www.wikidata.org/entity/Q3576935'), ('movieName', '23 Paces to Baker Street'), ('company', 'http://www.wikidata.org/entity/Q434841'), ('companyName', '20th Century Studios')]
# [('movie', 'http://www.wikidata.org/entity/Q1548602'), ('movieName', 'Only the Lonely'), ('company', 'http://www.wikidata.org/entity/Q434841'), ('companyName', '20th Century Studios')]
# [('movie', 'http://www.wikidata.org/entity/Q1757431'), ('movieName', 'The Girl in the Red Velvet Swing'), ('company', 'http://www.wikidata.org/entity/Q434841'), ('companyName', '20th Century Studios')]
# [('movie', 'http://www.wikidata.org/entity/Q1985667'), ('movieName', 'The Grissom Gang'), ('company', 'http://www.wikidata.org/entity/Q434841'), ('companyName', '20th Century Studios')]
# [('movie', 'http://www.wikidata.org/entity/Q1350631'), ('movieName', 'Off Limits'), ('company', 'http://www.wikidata.org/entity/Q434841'), ('companyName', '20th Century Studios')]
# [('movie', 'http://www.wikidata.org/entity/Q3061599'), ('movieName', 'The Counselor'), ('company', 'http://www.wikidata.org/entity/Q434841'), ('companyName', '20th Century Studios')]
# [('movie', 'http://www.wikidata.org/entity/Q3233309'), ('movieName', 'Violent Saturday'), ('company', 'http://www.wikidata.org/entity/Q434841'), ('companyName', '20th Century Studios')]
# [('movie', 'http://www.wikidata.org/entity/Q403830'), ('movieName', 'Less Than Zero'), ('company', 'http://www.wikidata.org/entity/Q434841'), ('companyName', '20th Century Studios')]
# [('movie', 'http://www.wikidata.org/entity/Q2715975'), ('movieName', 'Call Northside 777'), ('company', 'http://www.wikidata.org/entity/Q434841'), ('companyName', '20th Century Studios')]
# [('movie', 'http://www.wikidata.org/entity/Q3460360'), ('movieName', 'This Is My Affair'), ('company', 'http://www.wikidata.org/entity/Q434841'), ('companyName', '20th Century Studios')]
# [('movie', 'http://www.wikidata.org/entity/Q727334'), ('movieName', 'Regeneration'), ('company', 'http://www.wikidata.org/entity/Q434841'), ('companyName', '20th Century Studios')]
# [('movie', 'http://www.wikidata.org/entity/Q1198236'), ('movieName', 'Compulsion'), ('company', 'http://www.wikidata.org/entity/Q434841'), ('companyName', '20th Century Studios')]
# [('movie', 'http://www.wikidata.org/entity/Q1219363'), ('movieName', 'Black Widow'), ('company', 'http://www.wikidata.org/entity/Q434841'), ('companyName', '20th Century Studios')]
# [('movie', 'http://www.wikidata.org/entity/Q1457849'), ('movieName', "Thieves' Highway"), ('company', 'http://www.wikidata.org/entity/Q434841'), ('companyName', '20th Century Studios')]
# [('movie', 'http://www.wikidata.org/entity/Q4491086'), ('movieName', 'Charlie Chan on Broadway'), ('company', 'http://www.wikidata.org/entity/Q434841'), ('companyName', '20th Century Studios')]
# [('movie', 'http://www.wikidata.org/entity/Q514812'), ('movieName', 'Capone'), ('company', 'http://www.wikidata.org/entity/Q434841'), ('companyName', '20th Century Studios')]
# [('movie', 'http://www.wikidata.org/entity/Q1636538'), ('movieName', 'State of Grace'), ('company', 'http://www.wikidata.org/entity/Q434841'), ('companyName', '20th Century Studios')]
# [('movie', 'http://www.wikidata.org/entity/Q81845'), ('movieName', 'Vallanzasca - Angels of Evil'), ('company', 'http://www.wikidata.org/entity/Q434841'), ('companyName', '20th Century Studios')]
# [('movie', 'http://www.wikidata.org/entity/Q288150'), ('movieName', 'Freedom Writers'), ('company', 'http://www.wikidata.org/entity/Q17371413'), ('companyName', '2S Films')]
# [('movie', 'http://www.wikidata.org/entity/Q1402398'), ('movieName', 'Humanité'), ('company', 'http://www.wikidata.org/entity/Q97958214'), ('companyName', '3B Productions')]
# [('movie', 'http://www.wikidata.org/entity/Q81224'), ('movieName', 'Inside Man'), ('company', 'http://www.wikidata.org/entity/Q1138658'), ('companyName', '40 Acres & A Mule Filmworks')]
# [('movie', 'http://www.wikidata.org/entity/Q1529637'), ('movieName', 'Oldboy'), ('company', 'http://www.wikidata.org/entity/Q1138658'), ('companyName', '40 Acres & A Mule Filmworks')]
# [('movie', 'http://www.wikidata.org/entity/Q218458'), ('movieName', '25th Hour'), ('company', 'http://www.wikidata.org/entity/Q1138658'), ('companyName', '40 Acres & A Mule Filmworks')]
# [('movie', 'http://www.wikidata.org/entity/Q2268296'), ('movieName', 'Clockers'), ('company', 'http://www.wikidata.org/entity/Q1138658'), ('companyName', '40 Acres & A Mule Filmworks')]
# [('movie', 'http://www.wikidata.org/entity/Q19885337'), ('movieName', 'Chiraq'), ('company', 'http://www.wikidata.org/entity/Q1138658'), ('companyName', '40 Acres & A Mule Filmworks')]
# [('movie', 'http://www.wikidata.org/entity/Q1150713'), ('movieName', 'Summer of Sam'), ('company', 'http://www.wikidata.org/entity/Q1138658'), ('companyName', '40 Acres & A Mule Filmworks')]
# [('movie', 'http://www.wikidata.org/entity/Q81597'), ('movieName', 'New Jersey Drive'), ('company', 'http://www.wikidata.org/entity/Q1138658'), ('companyName', '40 Acres & A Mule Filmworks')]
# [('movie', 'http://www.wikidata.org/entity/Q16863042'), ('movieName', 'American Crime'), ('company', 'http://www.wikidata.org/entity/Q287218'), ('companyName', 'ABC Signature')]
# [('movie', 'http://www.wikidata.org/entity/Q7821735'), ('movieName', 'Tony'), ('company', 'http://www.wikidata.org/entity/Q4664352'), ('companyName', 'AbbottVision')]
# [('movie', 'http://www.wikidata.org/entity/Q27058562'), ('movieName', 'Der Athen Krimi - Trojanische Pferde'), ('company', 'http://www.wikidata.org/entity/Q266276'), ('companyName', 'Action Concept')]
# [('movie', 'http://www.wikidata.org/entity/Q12125409'), ('movieName', 'Kitty and the Bagman'), ('company', 'http://www.wikidata.org/entity/Q4680387'), ('companyName', 'Adams Packer Film Productions')]
# [('movie', 'http://www.wikidata.org/entity/Q1513821'), ('movieName', "For a Cop's Hide"), ('company', 'http://www.wikidata.org/entity/Q2399565'), ('companyName', 'Adel Productions')]
# [('movie', 'http://www.wikidata.org/entity/Q839294'), ('movieName', 'Death of a Corrupt Man'), ('company', 'http://www.wikidata.org/entity/Q2399565'), ('companyName', 'Adel Productions')]
# [('movie', 'http://www.wikidata.org/entity/Q3176410'), ('movieName', 'Jeff'), ('company', 'http://www.wikidata.org/entity/Q2399565'), ('companyName', 'Adel Productions')]
# [('movie', 'http://www.wikidata.org/entity/Q894172'), ('movieName', 'Borsalino'), ('company', 'http://www.wikidata.org/entity/Q2399565'), ('companyName', 'Adel Productions')]
# [('movie', 'http://www.wikidata.org/entity/Q1340986'), ('movieName', 'Two Men in Town'), ('company', 'http://www.wikidata.org/entity/Q2399565'), ('companyName', 'Adel Productions')]
# [('movie', 'http://www.wikidata.org/entity/Q1443738'), ('movieName', 'Roberto Succo'), ('company', 'http://www.wikidata.org/entity/Q20724296'), ('companyName', 'Agat Films & Cie - Ex Nihilo')]
# [('movie', 'http://www.wikidata.org/entity/Q2025754'), ('movieName', 'Stolen'), ('company', 'http://www.wikidata.org/entity/Q17081246'), ('companyName', 'Alchemy')]
# [('movie', 'http://www.wikidata.org/entity/Q47703'), ('movieName', 'The Godfather'), ('company', 'http://www.wikidata.org/entity/Q17305146'), ('companyName', 'Alfran Productions')]
# [('movie', 'http://www.wikidata.org/entity/Q2747218'), ('movieName', 'Victim'), ('company', 'http://www.wikidata.org/entity/Q4732568'), ('companyName', 'Allied Film Makers')]
# [('movie', 'http://www.wikidata.org/entity/Q482632'), ('movieName', 'Séance on a Wet Afternoon'), ('company', 'http://www.wikidata.org/entity/Q4732568'), ('companyName', 'Allied Film Makers')]
# [('movie', 'http://www.wikidata.org/entity/Q1719141'), ('movieName', 'Sweet Sixteen'), ('company', 'http://www.wikidata.org/entity/Q107009153'), ('companyName', 'Alta Films')]
# [('movie', 'http://www.wikidata.org/entity/Q208108'), ('movieName', 'Catch Me If You Can'), ('company', 'http://www.wikidata.org/entity/Q457893'), ('companyName', 'Amblin Entertainment')]
# [('movie', 'http://www.wikidata.org/entity/Q501995'), ('movieName', 'Cape Fear'), ('company', 'http://www.wikidata.org/entity/Q457893'), ('companyName', 'Amblin Entertainment')]
# [('movie', 'http://www.wikidata.org/entity/Q3521099'), ('movieName', 'The Grand Budapest Hotel'), ('company', 'http://www.wikidata.org/entity/Q3614056'), ('companyName', 'American Empirical Pictures')]
# [('movie', 'http://www.wikidata.org/entity/Q2663393'), ('movieName', 'Rolling Thunder'), ('company', 'http://www.wikidata.org/entity/Q465224'), ('companyName', 'American International Pictures')]
# [('movie', 'http://www.wikidata.org/entity/Q81995'), ('movieName', 'Dillinger'), ('company', 'http://www.wikidata.org/entity/Q465224'), ('companyName', 'American International Pictures')]
# [('movie', 'http://www.wikidata.org/entity/Q1212396'), ('movieName', 'Boxcar Bertha'), ('company', 'http://www.wikidata.org/entity/Q465224'), ('companyName', 'American International Pictures')]
# [('movie', 'http://www.wikidata.org/entity/Q7719130'), ('movieName', 'The Bonnie Parker Story'), ('company', 'http://www.wikidata.org/entity/Q465224'), ('companyName', 'American International Pictures')]
# [('movie', 'http://www.wikidata.org/entity/Q3224744'), ('movieName', 'The Black Monocle'), ('company', 'http://www.wikidata.org/entity/Q465224'), ('companyName', 'American International Pictures')]
# [('movie', 'http://www.wikidata.org/entity/Q1626875'), ('movieName', 'The Honeymoon Killers'), ('company', 'http://www.wikidata.org/entity/Q465224'), ('companyName', 'American International Pictures')]
# [('movie', 'http://www.wikidata.org/entity/Q4004029'), ('movieName', 'A Bullet for Pretty Boy'), ('company', 'http://www.wikidata.org/entity/Q465224'), ('companyName', 'American International Pictures')]
# [('movie', 'http://www.wikidata.org/entity/Q1119583'), ('movieName', 'Machine-Gun Kelly'), ('company', 'http://www.wikidata.org/entity/Q465224'), ('companyName', 'American International Pictures')]
# [('movie', 'http://www.wikidata.org/entity/Q5706688'), ('movieName', 'Hell Up in Harlem'), ('company', 'http://www.wikidata.org/entity/Q465224'), ('companyName', 'American International Pictures')]
# [('movie', 'http://www.wikidata.org/entity/Q2020244'), ('movieName', 'Swamp Women'), ('company', 'http://www.wikidata.org/entity/Q465224'), ('companyName', 'American International Pictures')]
# [('movie', 'http://www.wikidata.org/entity/Q2905338'), ('movieName', 'Black Caesar'), ('company', 'http://www.wikidata.org/entity/Q465224'), ('companyName', 'American International Pictures')]
# [('movie', 'http://www.wikidata.org/entity/Q1573923'), ('movieName', 'Hammett'), ('company', 'http://www.wikidata.org/entity/Q467348'), ('companyName', 'American Zoetrope')]
# [('movie', 'http://www.wikidata.org/entity/Q1617794'), ('movieName', "Tough Guys Don't Dance"), ('company', 'http://www.wikidata.org/entity/Q467348'), ('companyName', 'American Zoetrope')]
# [('movie', 'http://www.wikidata.org/entity/Q202326'), ('movieName', 'The Godfather Part III'), ('company', 'http://www.wikidata.org/entity/Q467348'), ('companyName', 'American Zoetrope')]
# [('movie', 'http://www.wikidata.org/entity/Q3077738'), ('movieName', 'The Bling Ring'), ('company', 'http://www.wikidata.org/entity/Q467348'), ('companyName', 'American Zoetrope')]
# [('movie', 'http://www.wikidata.org/entity/Q1009788'), ('movieName', 'The Conversation'), ('company', 'http://www.wikidata.org/entity/Q467348'), ('companyName', 'American Zoetrope')]
# [('movie', 'http://www.wikidata.org/entity/Q785351'), ('movieName', 'The Rainmaker'), ('company', 'http://www.wikidata.org/entity/Q467348'), ('companyName', 'American Zoetrope')]
# [('movie', 'http://www.wikidata.org/entity/Q639387'), ('movieName', 'The Cotton Club'), ('company', 'http://www.wikidata.org/entity/Q467348'), ('companyName', 'American Zoetrope')]
# [('movie', 'http://www.wikidata.org/entity/Q786562'), ('movieName', 'The Good Shepherd'), ('company', 'http://www.wikidata.org/entity/Q467348'), ('companyName', 'American Zoetrope')]
# [('movie', 'http://www.wikidata.org/entity/Q3842359'), ('movieName', 'Madhouse'), ('company', 'http://www.wikidata.org/entity/Q470851'), ('companyName', 'Amicus Productions')]
# [('movie', 'http://www.wikidata.org/entity/Q3423295'), ('movieName', 'The Psychopath'), ('company', 'http://www.wikidata.org/entity/Q470851'), ('companyName', 'Amicus Productions')]
# [('movie', 'http://www.wikidata.org/entity/Q1218827'), ('movieName', 'Scream and Scream Again'), ('company', 'http://www.wikidata.org/entity/Q470851'), ('companyName', 'Amicus Productions')]
# [('movie', 'http://www.wikidata.org/entity/Q13472766'), ('movieName', 'Pawn Shop Chronicles'), ('company', 'http://www.wikidata.org/entity/Q4752661'), ('companyName', 'Anchor Bay Entertainment')]
# [('movie', 'http://www.wikidata.org/entity/Q4927639'), ('movieName', 'Blood Money'), ('company', 'http://www.wikidata.org/entity/Q4763633'), ('companyName', 'Anglo-Hollandia')]
# [('movie', 'http://www.wikidata.org/entity/Q2667056'), ('movieName', "John Heriot's Wife"), ('company', 'http://www.wikidata.org/entity/Q4763633'), ('companyName', 'Anglo-Hollandia')]
# [('movie', 'http://www.wikidata.org/entity/Q27965056'), ('movieName', 'Detroit'), ('company', 'http://www.wikidata.org/entity/Q16242963'), ('companyName', 'Annapurna Pictures')]
# [('movie', 'http://www.wikidata.org/entity/Q253901'), ('movieName', 'Lawless'), ('company', 'http://www.wikidata.org/entity/Q16242963'), ('companyName', 'Annapurna Pictures')]
# [('movie', 'http://www.wikidata.org/entity/Q234789'), ('movieName', '44 Inch Chest'), ('company', 'http://www.wikidata.org/entity/Q567633'), ('companyName', 'Anonymous Content')]
# [('movie', 'http://www.wikidata.org/entity/Q301049'), ('movieName', "Winter's Bone"), ('company', 'http://www.wikidata.org/entity/Q567633'), ('companyName', 'Anonymous Content')]
# [('movie', 'http://www.wikidata.org/entity/Q485610'), ('movieName', 'Pineapple Express'), ('company', 'http://www.wikidata.org/entity/Q618091'), ('companyName', 'Apatow Productions')]
# [('movie', 'http://www.wikidata.org/entity/Q6462546'), ('movieName', 'La Flor de la mafia'), ('company', 'http://www.wikidata.org/entity/Q8204054'), ('companyName', 'Argentina Sono Film S.A.C.I.')]
# [('movie', 'http://www.wikidata.org/entity/Q5352062'), ('movieName', 'El Rufián'), ('company', 'http://www.wikidata.org/entity/Q8204054'), ('companyName', 'Argentina Sono Film S.A.C.I.')]
# [('movie', 'http://www.wikidata.org/entity/Q228937'), ('movieName', 'Au Hasard Balthazar'), ('company', 'http://www.wikidata.org/entity/Q2861044'), ('companyName', 'Argos Films')]
# [('movie', 'http://www.wikidata.org/entity/Q1402398'), ('movieName', 'Humanité'), ('company', 'http://www.wikidata.org/entity/Q2864822'), ('companyName', 'Arte France Cinéma')]
# [('movie', 'http://www.wikidata.org/entity/Q309459'), ('movieName', 'Paradise Now'), ('company', 'http://www.wikidata.org/entity/Q2864822'), ('companyName', 'Arte France Cinéma')]
# [('movie', 'http://www.wikidata.org/entity/Q909802'), ('movieName', 'The Punisher'), ('company', 'http://www.wikidata.org/entity/Q2865801'), ('companyName', 'Artisan Entertainment')]
# [('movie', 'http://www.wikidata.org/entity/Q1153794'), ('movieName', 'The Punisher'), ('company', 'http://www.wikidata.org/entity/Q2865801'), ('companyName', 'Artisan Entertainment')]
# [('movie', 'http://www.wikidata.org/entity/Q676928'), ('movieName', 'Light Sleeper'), ('company', 'http://www.wikidata.org/entity/Q2865801'), ('companyName', 'Artisan Entertainment')]
# [('movie', 'http://www.wikidata.org/entity/Q3486390'), ('movieName', 'Black Limelight'), ('company', 'http://www.wikidata.org/entity/Q200976'), ('companyName', 'Associated British Picture Corporation')]
# [('movie', 'http://www.wikidata.org/entity/Q960785'), ('movieName', 'Brighton Rock'), ('company', 'http://www.wikidata.org/entity/Q200976'), ('companyName', 'Associated British Picture Corporation')]
# [('movie', 'http://www.wikidata.org/entity/Q1152044'), ('movieName', 'Murder!'), ('company', 'http://www.wikidata.org/entity/Q200976'), ('companyName', 'Associated British Picture Corporation')]
# [('movie', 'http://www.wikidata.org/entity/Q3414563'), ('movieName', 'Cairo Road'), ('company', 'http://www.wikidata.org/entity/Q200976'), ('companyName', 'Associated British Picture Corporation')]
# [('movie', 'http://www.wikidata.org/entity/Q7045122'), ('movieName', 'No Trees in the Street'), ('company', 'http://www.wikidata.org/entity/Q200976'), ('companyName', 'Associated British Picture Corporation')]
# [('movie', 'http://www.wikidata.org/entity/Q6937759'), ('movieName', 'Murder in Soho'), ('company', 'http://www.wikidata.org/entity/Q200976'), ('companyName', 'Associated British Picture Corporation')]
# [('movie', 'http://www.wikidata.org/entity/Q6937689'), ('movieName', 'Murder Without Crime'), ('company', 'http://www.wikidata.org/entity/Q200976'), ('companyName', 'Associated British Picture Corporation')]
# [('movie', 'http://www.wikidata.org/entity/Q7232265'), ('movieName', 'Portrait of Clare'), ('company', 'http://www.wikidata.org/entity/Q200976'), ('companyName', 'Associated British Picture Corporation')]
# [('movie', 'http://www.wikidata.org/entity/Q26720585'), ('movieName', 'What Happened Then?'), ('company', 'http://www.wikidata.org/entity/Q200976'), ('companyName', 'Associated British Picture Corporation')]
# [('movie', 'http://www.wikidata.org/entity/Q7734629'), ('movieName', 'The Flying Squad'), ('company', 'http://www.wikidata.org/entity/Q200976'), ('companyName', 'Associated British Picture Corporation')]
# [('movie', 'http://www.wikidata.org/entity/Q7762625'), ('movieName', 'The Scotland Yard Mystery'), ('company', 'http://www.wikidata.org/entity/Q200976'), ('companyName', 'Associated British Picture Corporation')]
# [('movie', 'http://www.wikidata.org/entity/Q205694'), ('movieName', 'Number Seventeen'), ('company', 'http://www.wikidata.org/entity/Q200976'), ('companyName', 'Associated British Picture Corporation')]
# [('movie', 'http://www.wikidata.org/entity/Q7823844'), ('movieName', 'Too Hot to Handle'), ('company', 'http://www.wikidata.org/entity/Q200976'), ('companyName', 'Associated British Picture Corporation')]
# [('movie', 'http://www.wikidata.org/entity/Q5616349'), ('movieName', 'Guilt Is My Shadow'), ('company', 'http://www.wikidata.org/entity/Q200976'), ('companyName', 'Associated British Picture Corporation')]
# [('movie', 'http://www.wikidata.org/entity/Q5299683'), ('movieName', 'Double Confession'), ('company', 'http://www.wikidata.org/entity/Q200976'), ('companyName', 'Associated British Picture Corporation')]
# [('movie', 'http://www.wikidata.org/entity/Q916078'), ('movieName', 'Blackmail'), ('company', 'http://www.wikidata.org/entity/Q200976'), ('companyName', 'Associated British Picture Corporation')]
# [('movie', 'http://www.wikidata.org/entity/Q479038'), ('movieName', 'Piccadilly'), ('company', 'http://www.wikidata.org/entity/Q200976'), ('companyName', 'Associated British Picture Corporation')]
# [('movie', 'http://www.wikidata.org/entity/Q2607081'), ('movieName', 'Jungle Goddess'), ('company', 'http://www.wikidata.org/entity/Q16529036'), ('companyName', 'Associated Producers')]
# [('movie', 'http://www.wikidata.org/entity/Q309459'), ('movieName', 'Paradise Now'), ('company', 'http://www.wikidata.org/entity/Q108183168'), ('companyName', 'Augustus Film')]
# [('movie', 'http://www.wikidata.org/entity/Q391542'), ('movieName', 'Ned Kelly'), ('company', 'http://www.wikidata.org/entity/Q4824145'), ('companyName', 'Australian Film Commission')]
# [('movie', 'http://www.wikidata.org/entity/Q1171769'), ('movieName', 'The Man on the Train'), ('company', 'http://www.wikidata.org/entity/Q3429960'), ('companyName', 'Auvergne-Rhône-Alpes Cinéma')]
# [('movie', 'http://www.wikidata.org/entity/Q421984'), ('movieName', 'The Last Night of Childhood'), ('company', 'http://www.wikidata.org/entity/Q2875131'), ('companyName', 'Azerbaijanfilm')]
# [('movie', 'http://www.wikidata.org/entity/Q4200181'), ('movieName', 'Qanun namina'), ('company', 'http://www.wikidata.org/entity/Q2875131'), ('companyName', 'Azerbaijanfilm')]
# [('movie', 'http://www.wikidata.org/entity/Q2394769'), ('movieName', 'Ill Manors'), ('company', 'http://www.wikidata.org/entity/Q971446'), ('companyName', 'BBC Film')]
# [('movie', 'http://www.wikidata.org/entity/Q733677'), ('movieName', 'Match Point'), ('company', 'http://www.wikidata.org/entity/Q971446'), ('companyName', 'BBC Film')]
# [('movie', 'http://www.wikidata.org/entity/Q663341'), ('movieName', 'One Day in September'), ('company', 'http://www.wikidata.org/entity/Q971446'), ('companyName', 'BBC Film')]
# [('movie', 'http://www.wikidata.org/entity/Q17344458'), ('movieName', 'Mr. Holmes'), ('company', 'http://www.wikidata.org/entity/Q971446'), ('companyName', 'BBC Film')]
# [('movie', 'http://www.wikidata.org/entity/Q1719141'), ('movieName', 'Sweet Sixteen'), ('company', 'http://www.wikidata.org/entity/Q971446'), ('companyName', 'BBC Film')]
# [('movie', 'http://www.wikidata.org/entity/Q682002'), ('movieName', 'scoop'), ('company', 'http://www.wikidata.org/entity/Q971446'), ('companyName', 'BBC Film')]
# [('movie', 'http://www.wikidata.org/entity/Q151903'), ('movieName', 'Dirty Pretty Things'), ('company', 'http://www.wikidata.org/entity/Q971446'), ('companyName', 'BBC Film')]
# [('movie', 'http://www.wikidata.org/entity/Q915845'), ('movieName', 'Brighton Rock'), ('company', 'http://www.wikidata.org/entity/Q971446'), ('companyName', 'BBC Film')]
# [('movie', 'http://www.wikidata.org/entity/Q1854561'), ('movieName', 'Millions'), ('company', 'http://www.wikidata.org/entity/Q971446'), ('companyName', 'BBC Film')]
# [('movie', 'http://www.wikidata.org/entity/Q4996798'), ('movieName', 'Bullet Boy'), ('company', 'http://www.wikidata.org/entity/Q971446'), ('companyName', 'BBC Film')]
# [('movie', 'http://www.wikidata.org/entity/Q3521099'), ('movieName', 'The Grand Budapest Hotel'), ('company', 'http://www.wikidata.org/entity/Q100706708'), ('companyName', 'Babelsberg Film GmbH')]
# [('movie', 'http://www.wikidata.org/entity/Q738456'), ('movieName', 'Donnie Brasco'), ('company', 'http://www.wikidata.org/entity/Q17346715'), ('companyName', 'Baltimore Pictures')]
# [('movie', 'http://www.wikidata.org/entity/Q1145732'), ('movieName', 'Sleepers'), ('company', 'http://www.wikidata.org/entity/Q17346715'), ('companyName', 'Baltimore Pictures')]
# [('movie', 'http://www.wikidata.org/entity/Q241085'), ('movieName', 'Bugsy'), ('company', 'http://www.wikidata.org/entity/Q17346715'), ('companyName', 'Baltimore Pictures')]
# [('movie', 'http://www.wikidata.org/entity/Q2003850'), ('movieName', 'Next of Kin'), ('company', 'http://www.wikidata.org/entity/Q4863949'), ('companyName', 'Barry & Enright Productions')]
# [('movie', 'http://www.wikidata.org/entity/Q1655702'), ('movieName', 'Vier gegen die Bank'), ('company', 'http://www.wikidata.org/entity/Q648034'), ('companyName', 'Bavaria Film')]
# [('movie', 'http://www.wikidata.org/entity/Q18819289'), ('movieName', 'Tatort: Hydra'), ('company', 'http://www.wikidata.org/entity/Q648034'), ('companyName', 'Bavaria Film')]
# [('movie', 'http://www.wikidata.org/entity/Q2070042'), ('movieName', 'The Swiss Conspiracy'), ('company', 'http://www.wikidata.org/entity/Q648034'), ('companyName', 'Bavaria Film')]
# [('movie', 'http://www.wikidata.org/entity/Q16294949'), ('movieName', 'Tatort: Der Hammer'), ('company', 'http://www.wikidata.org/entity/Q648034'), ('companyName', 'Bavaria Film')]
# [('movie', 'http://www.wikidata.org/entity/Q39005'), ('movieName', 'The Pleasure Garden'), ('company', 'http://www.wikidata.org/entity/Q648034'), ('companyName', 'Bavaria Film')]
# [('movie', 'http://www.wikidata.org/entity/Q82332636'), ('movieName', 'Freud'), ('company', 'http://www.wikidata.org/entity/Q648034'), ('companyName', 'Bavaria Film')]
# 200

# %% [markdown]
# Final query for this task

# %%
#The last thing its count all the movies for each company.
queryString = """
SELECT DISTINCT ?company ?companyName (COUNT(*) AS ?crimefilms)
WHERE {
   # bind something
   # ?movie wdt:P136 wd:Q959790.
   # ?movie wdt:P272 ?company. 
   # ?company wdt:P31 ?type .
            #Television production company    #film production company 
   VALUES ?type {wd:Q10689397                    wd:Q1762059}
   # get the label
   
   # ?company sc:name ?companyName .
}
ORDER BY DESC (?crimefilms) #I order by ?crimefilms to get the companies with more films.
LIMIT 5 #I put the limit 5 because I only want the top-5.
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('company', 'http://www.wikidata.org/entity/Q434841'), ('companyName', '20th Century Studios'), ('crimefilms', '180')]
# [('company', 'http://www.wikidata.org/entity/Q126399'), ('companyName', 'Warner Bros.'), ('crimefilms', '164')]
# [('company', 'http://www.wikidata.org/entity/Q186941'), ('companyName', 'Columbia Pictures'), ('crimefilms', '118')]
# [('company', 'http://www.wikidata.org/entity/Q168383'), ('companyName', 'Universal Pictures'), ('crimefilms', '113')]
# [('company', 'http://www.wikidata.org/entity/Q179200'), ('companyName', 'Metro-Goldwyn-Mayer'), ('crimefilms', '112')]
# 5

# %% [markdown]
# ## Task 6
# Find the company (amongst television production company and film production company) which distributed more films (of any kind of film genre) that they did not produce (the result set must be a list of triples company IRI, label and #film).

# %%
#First I get all the films 
queryString = """
SELECT DISTINCT ?film ?filmName
WHERE {
   # bind something
   # ?film wdt:P31 wd:Q11424.
   
   
   # get the label
   # ?film sc:name ?filmName.
  
}
ORDER BY ?filmName
LIMIT 50
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('film', 'http://www.wikidata.org/entity/Q4540204'), ('filmName', '!Women Art Revolution')]
# [('film', 'http://www.wikidata.org/entity/Q4032288'), ('filmName', '"713" Requests Permission to Land')]
# [('film', 'http://www.wikidata.org/entity/Q93765322'), ('filmName', '"By the railroad" film')]
# [('film', 'http://www.wikidata.org/entity/Q615254'), ('filmName', '"Crocodile" Dundee')]
# [('film', 'http://www.wikidata.org/entity/Q1140745'), ('filmName', '"Crocodile" Dundee II')]
# [('film', 'http://www.wikidata.org/entity/Q16691116'), ('filmName', '"Dream" Agency')]
# [('film', 'http://www.wikidata.org/entity/Q3596104'), ('filmName', '"FF.SS." – Cioè: "...che mi hai portato a fare sopra a Posillipo se non mi vuoi più bene?"')]
# [('film', 'http://www.wikidata.org/entity/Q4540285'), ('filmName', '"Good Hair" and Other Dubious Distinctions')]
# [('film', 'http://www.wikidata.org/entity/Q93764465'), ('filmName', '"Interrogation", film, 1982')]
# [('film', 'http://www.wikidata.org/entity/Q821560'), ('filmName', '"Pimpernel" Smith')]
# [('film', 'http://www.wikidata.org/entity/Q3817474'), ('filmName', '"Tobago" Changes its Course')]
# [('film', 'http://www.wikidata.org/entity/Q3596113'), ('filmName', '"Weird Al" Yankovic Live!')]
# [('film', 'http://www.wikidata.org/entity/Q4540329'), ('filmName', '"Weird Al" Yankovic Live!: The Alpocalypse Tour')]
# [('film', 'http://www.wikidata.org/entity/Q3596108'), ('filmName', '"Weird Al" Yankovic: The Ultimate Collection')]
# [('film', 'http://www.wikidata.org/entity/Q3596112'), ('filmName', '"Weird Al" Yankovic: The Ultimate Video Collection')]
# [('film', 'http://www.wikidata.org/entity/Q3596111'), ('filmName', '"Weird Al" Yankovic: The Videos')]
# [('film', 'http://www.wikidata.org/entity/Q2299302'), ('filmName', '#1 Cheerleader Camp')]
# [('film', 'http://www.wikidata.org/entity/Q91439580'), ('filmName', '#73, Shantinivasa')]
# [('film', 'http://www.wikidata.org/entity/Q85740993'), ('filmName', '#Alive')]
# [('film', 'http://www.wikidata.org/entity/Q96790752'), ('filmName', '#AnneFrank. Parallel Stories')]
# [('film', 'http://www.wikidata.org/entity/Q29959717'), ('filmName', '#DigitalLivesMatter')]
# [('film', 'http://www.wikidata.org/entity/Q108144643'), ('filmName', '#Home')]
# [('film', 'http://www.wikidata.org/entity/Q20949884'), ('filmName', '#Horror')]
# [('film', 'http://www.wikidata.org/entity/Q79999076'), ('filmName', '#Iamhere')]
# [('film', 'http://www.wikidata.org/entity/Q59690818'), ('filmName', '#Lingo')]
# [('film', 'http://www.wikidata.org/entity/Q24639973'), ('filmName', '#OntheShouldersofGiants')]
# [('film', 'http://www.wikidata.org/entity/Q24708048'), ('filmName', '#Resistayol')]
# [('film', 'http://www.wikidata.org/entity/Q64990912'), ('filmName', '#Roxy')]
# [('film', 'http://www.wikidata.org/entity/Q50331271'), ('filmName', '#Rucker50')]
# [('film', 'http://www.wikidata.org/entity/Q102968816'), ('filmName', '#WeAreMany')]
# [('film', 'http://www.wikidata.org/entity/Q108353393'), ('filmName', '#dogpoopgirl')]
# [('film', 'http://www.wikidata.org/entity/Q47472344'), ('filmName', '#realityhigh')]
# [('film', 'http://www.wikidata.org/entity/Q1195819'), ('filmName', '$')]
# [('film', 'http://www.wikidata.org/entity/Q17985036'), ('filmName', '$1,000 Reward')]
# [('film', 'http://www.wikidata.org/entity/Q20649132'), ('filmName', '$1,000 a Touchdown')]
# [('film', 'http://www.wikidata.org/entity/Q50650175'), ('filmName', '$10 Raise')]
# [('film', 'http://www.wikidata.org/entity/Q19543496'), ('filmName', '$100,000')]
# [('film', 'http://www.wikidata.org/entity/Q47500716'), ('filmName', '$20 a Week')]
# [('film', 'http://www.wikidata.org/entity/Q42384855'), ('filmName', '$30,000')]
# [('film', 'http://www.wikidata.org/entity/Q63924545'), ('filmName', '$50,000 Reward')]
# [('film', 'http://www.wikidata.org/entity/Q106237879'), ('filmName', '$avvy')]
# [('film', 'http://www.wikidata.org/entity/Q4540363'), ('filmName', '$pent')]
# [('film', 'http://www.wikidata.org/entity/Q73811235'), ('filmName', '&#39;Tis the Bull')]
# [('film', 'http://www.wikidata.org/entity/Q4540370'), ('filmName', '&ME')]
# [('film', 'http://www.wikidata.org/entity/Q228659'), ('filmName', "'38 – Vienna Before the Fall")]
# [('film', 'http://www.wikidata.org/entity/Q101245461'), ('filmName', "'49–'17")]
# [('film', 'http://www.wikidata.org/entity/Q4540385'), ('filmName', "'68")]
# [('film', 'http://www.wikidata.org/entity/Q31724156'), ('filmName', "'71 Er Maa Jononi")]
# [('film', 'http://www.wikidata.org/entity/Q15927133'), ('filmName', "'76")]
# [('film', 'http://www.wikidata.org/entity/Q57699362'), ('filmName', "'76")]
# 50

# %%
#Now I get the companies who distributed them
queryString = """
SELECT DISTINCT ?filmName ?distributorName 
WHERE {

   # bind something
   # ?film wdt:P31 wd:Q11424.
   # ?film wdt:P750 ?distributor.
   
  
   # get the label
   # ?film sc:name ?filmName.
    # ?distributor sc:name ?distributorName .
    
}
ORDER BY ?filmName ?distributorName ?producerName
LIMIT 200
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('filmName', '!Women Art Revolution'), ('distributorName', 'Zeitgeist Films')]
# [('filmName', '"Crocodile" Dundee'), ('distributorName', 'FandangoNow')]
# [('filmName', '"Crocodile" Dundee'), ('distributorName', 'Netflix')]
# [('filmName', '"Crocodile" Dundee'), ('distributorName', 'Paramount Pictures')]
# [('filmName', '"Crocodile" Dundee II'), ('distributorName', 'FandangoNow')]
# [('filmName', '"Crocodile" Dundee II'), ('distributorName', 'Netflix')]
# [('filmName', '"Crocodile" Dundee II'), ('distributorName', 'Paramount Pictures')]
# [('filmName', '"Weird Al" Yankovic Live!'), ('distributorName', 'Volcano')]
# [('filmName', '"Weird Al" Yankovic Live!: The Alpocalypse Tour'), ('distributorName', 'Comedy Central')]
# [('filmName', '"Weird Al" Yankovic: The Ultimate Video Collection'), ('distributorName', 'Volcano')]
# [('filmName', '#1 Cheerleader Camp'), ('distributorName', 'Netflix')]
# [('filmName', '#1 Cheerleader Camp'), ('distributorName', 'The Asylum')]
# [('filmName', '#Alive'), ('distributorName', 'Netflix')]
# [('filmName', '#AnneFrank. Parallel Stories'), ('distributorName', 'Netflix')]
# [('filmName', '#Horror'), ('distributorName', 'IFC Films')]
# [('filmName', '#Horror'), ('distributorName', 'Netflix')]
# [('filmName', '#Roxy'), ('distributorName', 'Netflix')]
# [('filmName', '#Roxy'), ('distributorName', 'iTunes')]
# [('filmName', '#Rucker50'), ('distributorName', 'Netflix')]
# [('filmName', '#realityhigh'), ('distributorName', 'Netflix')]
# [('filmName', '$'), ('distributorName', 'Columbia Pictures')]
# [('filmName', '$'), ('distributorName', 'FandangoNow')]
# [('filmName', '$'), ('distributorName', 'Netflix')]
# [('filmName', "'68"), ('distributorName', 'New World Pictures')]
# [('filmName', "'Blue Blazes' Rawden"), ('distributorName', 'Paramount Pictures')]
# [('filmName', "'Gator Bait"), ('distributorName', 'Dimension Pictures')]
# [('filmName', "'Gator Bait II: Cajun Justice"), ('distributorName', 'Paramount Pictures')]
# [('filmName', "'If Only' Jim"), ('distributorName', 'Universal Pictures')]
# [('filmName', "'Neath Brooklyn Bridge"), ('distributorName', 'Monogram Pictures')]
# [('filmName', "'Neath the Arizona Skies"), ('distributorName', 'Monogram Pictures')]
# [('filmName', "'Neath the Arizona Skies"), ('distributorName', 'Netflix')]
# [('filmName', "'R Xmas"), ('distributorName', 'Artisan Entertainment')]
# [('filmName', "'R Xmas"), ('distributorName', 'Netflix')]
# [('filmName', "'Til There Was You"), ('distributorName', 'Netflix')]
# [('filmName', "'Til There Was You"), ('distributorName', 'Paramount Pictures')]
# [('filmName', "'Til We Meet Again"), ('distributorName', 'Warner Bros.')]
# [('filmName', "'Twas Ever Thus"), ('distributorName', 'Paramount Pictures')]
# [('filmName', "'Twas the Night Before Christmas"), ('distributorName', 'American Broadcasting Company')]
# [('filmName', "'night, Mother"), ('distributorName', 'Universal Pictures')]
# [('filmName', '(500) Days of Summer'), ('distributorName', 'FandangoNow')]
# [('filmName', '(500) Days of Summer'), ('distributorName', 'Netflix')]
# [('filmName', '(500) Days of Summer'), ('distributorName', 'Searchlight Pictures')]
# [('filmName', '(Dis)Honesty: The Truth About Lies'), ('distributorName', 'Netflix')]
# [('filmName', '(Romance) in the Digital Age'), ('distributorName', 'Comedy Dynamics')]
# [('filmName', '(T)ERROR'), ('distributorName', 'Netflix')]
# [('filmName', '(Untitled)'), ('distributorName', 'Samuel Goldwyn Films')]
# [('filmName', '+1'), ('distributorName', 'ADS Service')]
# [('filmName', '+1'), ('distributorName', 'IFC Films')]
# [('filmName', '-30-'), ('distributorName', 'Warner Bros.')]
# [('filmName', '...All the Marbles'), ('distributorName', 'Metro-Goldwyn-Mayer')]
# [('filmName', '...And If We All Lived Together'), ('distributorName', 'BAC Films')]
# [('filmName', '...And Justice for All'), ('distributorName', 'Columbia Pictures')]
# [('filmName', '...And Justice for All'), ('distributorName', 'Netflix')]
# [('filmName', '...One Third of a Nation...'), ('distributorName', 'Paramount Pictures')]
# [('filmName', '...So Goes the Nation'), ('distributorName', 'IFC Films')]
# [('filmName', '...When Love Happens'), ('distributorName', 'Netflix')]
# [('filmName', '...tick...tick...tick...'), ('distributorName', 'Metro-Goldwyn-Mayer')]
# [('filmName', '.45'), ('distributorName', 'Netflix')]
# [('filmName', '.45'), ('distributorName', 'Rockstar Leeds')]
# [('filmName', '.com for Murder'), ('distributorName', 'Netflix')]
# [('filmName', '.hack//The Movie'), ('distributorName', 'Bandai Visual')]
# [('filmName', '0 1 0'), ('distributorName', 'Gutek Film')]
# [('filmName', '00 Schneider – Jagd auf Nihil Baxter'), ('distributorName', 'Netflix')]
# [('filmName', '06/05'), ('distributorName', 'Netflix')]
# [('filmName', '1'), ('distributorName', 'Exclusive Media')]
# [('filmName', '1'), ('distributorName', 'Mozinet')]
# [('filmName', '1'), ('distributorName', 'Netflix')]
# [('filmName', "1 2 3 Viva l'Algérie"), ('distributorName', 'Spira')]
# [('filmName', '1 Chance 2 Dance'), ('distributorName', 'Netflix')]
# [('filmName', '1 Day'), ('distributorName', 'Netflix')]
# [('filmName', '1 Mile to You'), ('distributorName', 'Gravitas Ventures')]
# [('filmName', '1 Night in China'), ('distributorName', 'Red Light District Video')]
# [('filmName', '1 Night in Paris'), ('distributorName', 'Red Light District Video')]
# [('filmName', '1 a Minute'), ('distributorName', 'Warner Bros.')]
# [('filmName', '1%'), ('distributorName', 'A24')]
# [('filmName', '1, 2, 3, Sun'), ('distributorName', 'Netflix')]
# [('filmName', '1,000 Dollars a Minute'), ('distributorName', 'Republic Pictures')]
# [('filmName', '1,778 Stories of Me and My Wife'), ('distributorName', 'Toho')]
# [('filmName', '1-2-3 Corona'), ('distributorName', 'Progress Film')]
# [('filmName', '1-2-3 Go'), ('distributorName', 'Metro-Goldwyn-Mayer')]
# [('filmName', '10'), ('distributorName', 'FandangoNow')]
# [('filmName', '10'), ('distributorName', 'Netflix')]
# [('filmName', '10'), ('distributorName', 'Warner Bros.')]
# [('filmName', '10 Cent Pistol'), ('distributorName', 'Phase 4 Films')]
# [('filmName', '10 Cloverfield Lane'), ('distributorName', 'FandangoNow')]
# [('filmName', '10 Cloverfield Lane'), ('distributorName', 'Netflix')]
# [('filmName', '10 Cloverfield Lane'), ('distributorName', 'Paramount Pictures')]
# [('filmName', '10 Cloverfield Lane'), ('distributorName', 'UIP-Dunafilm')]
# [('filmName', '10 Cloverfield Lane'), ('distributorName', 'Vudu')]
# [('filmName', '10 Days in Sun City'), ('distributorName', 'Netflix')]
# [('filmName', '10 Endrathukulla'), ('distributorName', 'Fox Star Studios')]
# [('filmName', '10 Items or Less'), ('distributorName', 'Netflix')]
# [('filmName', '10 Items or Less'), ('distributorName', 'THINKFilm')]
# [('filmName', '10 MPH'), ('distributorName', 'Netflix')]
# [('filmName', '10 Minutes'), ('distributorName', 'Lotte Cultureworks')]
# [('filmName', '10 Promises to My Dog'), ('distributorName', 'Netflix')]
# [('filmName', '10 Promises to My Dog'), ('distributorName', 'Shochiku')]
# [('filmName', '10 Questions for the Dalai Lama'), ('distributorName', 'FandangoNow')]
# [('filmName', '10 Questions for the Dalai Lama'), ('distributorName', 'Netflix')]
# [('filmName', '10 Rillington Place'), ('distributorName', 'Columbia Pictures')]
# [('filmName', '10 Rillington Place'), ('distributorName', 'FandangoNow')]
# [('filmName', '10 Rillington Place'), ('distributorName', 'Netflix')]
# [('filmName', '10 Rules for Sleeping Around'), ('distributorName', 'Netflix')]
# [('filmName', '10 Rules for Sleeping Around'), ('distributorName', 'Screen Media Films')]
# [('filmName', '10 Things I Hate About You'), ('distributorName', 'Disney+')]
# [('filmName', '10 Things I Hate About You'), ('distributorName', 'FandangoNow')]
# [('filmName', '10 Things I Hate About You'), ('distributorName', 'InterCom')]
# [('filmName', '10 Things I Hate About You'), ('distributorName', 'Netflix')]
# [('filmName', '10 Years'), ('distributorName', 'ADS Service')]
# [('filmName', '10 Years'), ('distributorName', 'Anchor Bay Entertainment')]
# [('filmName', '10 Years'), ('distributorName', 'Hulu')]
# [('filmName', '10 Years'), ('distributorName', 'Netflix')]
# [('filmName', '10 jours sans maman'), ('distributorName', 'Big Bang Media')]
# [('filmName', '10 regole per fare innamorare'), ('distributorName', 'Lucky Red Distribuzione')]
# [('filmName', '10 to Midnight'), ('distributorName', 'Netflix')]
# [('filmName', '10 to Midnight'), ('distributorName', 'The Cannon Group')]
# [('filmName', '10,000 BC'), ('distributorName', 'FandangoNow')]
# [('filmName', '10,000 BC'), ('distributorName', 'InterCom')]
# [('filmName', '10,000 BC'), ('distributorName', 'Netflix')]
# [('filmName', '10,000 Hours'), ('distributorName', 'VIVA Films')]
# [('filmName', '10,000 km'), ('distributorName', 'Broad Green Pictures')]
# [('filmName', '10,000 km'), ('distributorName', 'Cirko Film')]
# [('filmName', '10,000 km'), ('distributorName', 'Emperor Motion Pictures')]
# [('filmName', '10,000 km'), ('distributorName', 'Gravitas Ventures')]
# [('filmName', '10,000 km'), ('distributorName', 'UA Cinemas')]
# [('filmName', '10.0 Earthquake'), ('distributorName', 'Hulu')]
# [('filmName', '10.0 Earthquake'), ('distributorName', 'MarVista Entertainment')]
# [('filmName', '100 Days'), ('distributorName', 'Dynit')]
# [('filmName', '100 Days Before the Command'), ('distributorName', 'Peccadillo Pictures')]
# [('filmName', '100 Days of Solitude'), ('distributorName', 'Netflix')]
# [('filmName', '100 Days with Mr. Arrogant'), ('distributorName', 'Cinema Service')]
# [('filmName', '100 Degrees Below Zero'), ('distributorName', 'Vudu')]
# [('filmName', '100 Feet'), ('distributorName', 'Netflix')]
# [('filmName', '100 Feet'), ('distributorName', 'Voltage Pictures')]
# [('filmName', '100 Ghost Street: The Return of Richard Speck'), ('distributorName', 'Netflix')]
# [('filmName', '100 Girls'), ('distributorName', 'Lionsgate')]
# [('filmName', '100 Girls'), ('distributorName', 'Netflix')]
# [('filmName', '100 Rifles'), ('distributorName', '20th Century Studios')]
# [('filmName', '100 Rifles'), ('distributorName', 'Netflix')]
# [('filmName', '100 Streets'), ('distributorName', 'Samuel Goldwyn Films')]
# [('filmName', '100 Tears'), ('distributorName', 'Netflix')]
# [('filmName', '100 Things'), ('distributorName', 'Big Bang Media')]
# [('filmName', '100 Things'), ('distributorName', 'Netflix')]
# [('filmName', '100 metros'), ('distributorName', 'Filmax International')]
# [('filmName', '100 metros'), ('distributorName', 'Netflix')]
# [('filmName', '100% Coco'), ('distributorName', 'Dutch FilmWorks')]
# [('filmName', '100% Love'), ('distributorName', 'Geetha Arts')]
# [('filmName', '100% Wolf'), ('distributorName', 'ADS Service')]
# [('filmName', '100% Wolf'), ('distributorName', 'Zíma')]
# [('filmName', '1001 Arabian Nights'), ('distributorName', 'Columbia Pictures')]
# [('filmName', '1001 Grams'), ('distributorName', 'Netflix')]
# [('filmName', '1001 Grams'), ('distributorName', 'Vertigo Média')]
# [('filmName', '101 Rent Boys'), ('distributorName', 'Strand Releasing')]
# [('filmName', '101 Reykjavík'), ('distributorName', 'Netflix')]
# [('filmName', '102 Not Out'), ('distributorName', 'Columbia Pictures')]
# [('filmName', '10:10 (film)'), ('distributorName', 'Morpheus Media Ventures')]
# [('filmName', '10:30 P.M. Summer'), ('distributorName', 'Netflix')]
# [('filmName', '10th & Wolf'), ('distributorName', 'THINKFilm')]
# [('filmName', '10th District Court'), ('distributorName', 'Les films du losange')]
# [('filmName', '10x10'), ('distributorName', 'Hulu')]
# [('filmName', '10x10'), ('distributorName', 'Vertical Entertainment')]
# [('filmName', '11 A.M. (film)'), ('distributorName', 'CJ Entertainment')]
# [('filmName', '11 Harrowhouse'), ('distributorName', '20th Century Studios')]
# [('filmName', '11 Harrowhouse'), ('distributorName', 'Netflix')]
# [('filmName', '11 Minutes'), ('distributorName', 'Hulu')]
# [('filmName', '11 Minutes'), ('distributorName', 'Kino Świat')]
# [('filmName', '11-11-11'), ('distributorName', 'Columbia Pictures')]
# [('filmName', '11.6'), ('distributorName', 'Netflix')]
# [('filmName', '11.6'), ('distributorName', 'Wild Bunch')]
# [('filmName', '11/11/11'), ('distributorName', 'The Asylum')]
# [('filmName', '11:11'), ('distributorName', 'Moviemax')]
# [('filmName', '11:14'), ('distributorName', 'Netflix')]
# [('filmName', '11:14'), ('distributorName', 'New Line Cinema')]
# [('filmName', '11Eleven Project'), ('distributorName', 'Titan View')]
# [('filmName', '12'), ('distributorName', '01 Distribution')]
# [('filmName', '12 Angry Men'), ('distributorName', 'MOKÉP')]
# [('filmName', '12 Angry Men'), ('distributorName', 'Netflix')]
# [('filmName', '12 Feet Deep'), ('distributorName', 'MarVista Entertainment')]
# [('filmName', '12 Monkeys'), ('distributorName', 'FandangoNow')]
# [('filmName', '12 Monkeys'), ('distributorName', 'Netflix')]
# [('filmName', '12 Monkeys'), ('distributorName', 'UIP-Dunafilm')]
# [('filmName', "12 O'Clock Boys"), ('distributorName', 'Hulu')]
# [('filmName', "12 O'Clock Boys"), ('distributorName', 'Oscilloscope')]
# [('filmName', '12 Paces Without a Head'), ('distributorName', 'Warner Bros.')]
# [('filmName', '12 Rounds'), ('distributorName', '20th Century Studios')]
# [('filmName', '12 Rounds'), ('distributorName', 'FandangoNow')]
# [('filmName', '12 Rounds'), ('distributorName', 'Netflix')]
# [('filmName', '12 Strong'), ('distributorName', 'InterCom')]
# [('filmName', '12 Strong'), ('distributorName', 'Netflix')]
# [('filmName', '12 Strong'), ('distributorName', 'Warner Bros.')]
# [('filmName', '12 Years a Slave'), ('distributorName', 'FandangoNow')]
# [('filmName', '12 Years a Slave'), ('distributorName', 'InterCom')]
# [('filmName', '12 Years a Slave'), ('distributorName', 'Netflix')]
# [('filmName', '12 Years a Slave'), ('distributorName', 'ProVideo')]
# [('filmName', '12 and Holding'), ('distributorName', 'IFC Films')]
# [('filmName', '12 and Holding'), ('distributorName', 'Netflix')]
# [('filmName', '12 to the Moon'), ('distributorName', 'Columbia Pictures')]
# [('filmName', '12/12/12'), ('distributorName', 'Netflix')]
# [('filmName', '12/12/12'), ('distributorName', 'Vudu')]
# [('filmName', '120'), ('distributorName', 'Özen Film')]
# 200

# %%
#Now I get also the company who produced them. 
queryString = """
SELECT DISTINCT ?filmName ?distributorName ?producerName
WHERE {

   # bind something
   # ?film wdt:P31 wd:Q11424.
   # ?film wdt:P750 ?distributor.
   # ?film wdt:P272 ?producer .

   # get the label
   # ?film sc:name ?filmName.
    # ?distributor sc:name ?distributorName .
    # ?producer sc:name ?producerName .
}
ORDER BY ?filmName ?distributorName ?producerName
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('filmName', '"Crocodile" Dundee'), ('distributorName', 'FandangoNow'), ('producerName', 'Paramount Pictures')]
# [('filmName', '"Crocodile" Dundee'), ('distributorName', 'Netflix'), ('producerName', 'Paramount Pictures')]
# [('filmName', '"Crocodile" Dundee'), ('distributorName', 'Paramount Pictures'), ('producerName', 'Paramount Pictures')]
# [('filmName', '"Crocodile" Dundee II'), ('distributorName', 'FandangoNow'), ('producerName', 'Paramount Pictures')]
# [('filmName', '"Crocodile" Dundee II'), ('distributorName', 'Netflix'), ('producerName', 'Paramount Pictures')]
# [('filmName', '"Crocodile" Dundee II'), ('distributorName', 'Paramount Pictures'), ('producerName', 'Paramount Pictures')]
# [('filmName', '#1 Cheerleader Camp'), ('distributorName', 'Netflix'), ('producerName', 'The Asylum')]
# [('filmName', '#1 Cheerleader Camp'), ('distributorName', 'The Asylum'), ('producerName', 'The Asylum')]
# [('filmName', "'Neath the Arizona Skies"), ('distributorName', 'Monogram Pictures'), ('producerName', 'Lone Star Productions')]
# [('filmName', "'Neath the Arizona Skies"), ('distributorName', 'Netflix'), ('producerName', 'Lone Star Productions')]
# [('filmName', "'Til We Meet Again"), ('distributorName', 'Warner Bros.'), ('producerName', 'Warner Bros.')]
# [('filmName', "'night, Mother"), ('distributorName', 'Universal Pictures'), ('producerName', 'Universal Pictures')]
# [('filmName', '-30-'), ('distributorName', 'Warner Bros.'), ('producerName', 'Mark VII Limited')]
# [('filmName', '...And Justice for All'), ('distributorName', 'Columbia Pictures'), ('producerName', 'Columbia Pictures')]
# [('filmName', '...And Justice for All'), ('distributorName', 'Netflix'), ('producerName', 'Columbia Pictures')]
# [('filmName', '.hack//The Movie'), ('distributorName', 'Bandai Visual'), ('producerName', 'CyberConnect2')]
# [('filmName', '1 Night in China'), ('distributorName', 'Red Light District Video'), ('producerName', 'Red Light District Video')]
# [('filmName', '1 Night in Paris'), ('distributorName', 'Red Light District Video'), ('producerName', 'Red Light District Video')]
# [('filmName', '1, 2, 3, Sun'), ('distributorName', 'Netflix'), ('producerName', 'Gaumont Film Company')]
# [('filmName', '1-2-3 Corona'), ('distributorName', 'Progress Film'), ('producerName', 'DEFA')]
# 20

# %%
#I try now only the distributors that not produced the movies but they distributed them. 
queryString = """
SELECT DISTINCT ?filmName ?distributorName ?producerName
WHERE {

   # bind something
   # ?film wdt:P31 wd:Q11424.
   # ?film wdt:P750 ?distributor.
   # ?film wdt:P272 ?producer .
   
   FILTER (?distributor != ?producer) #The values of the producer and the distributor can't be the same.
   # get the label
   # ?film sc:name ?filmName.
    # ?distributor sc:name ?distributorName .
    # ?producer sc:name ?producerName .
}
ORDER BY ?filmName ?distributorName ?producerName
LIMIT 50
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('filmName', '"Crocodile" Dundee'), ('distributorName', 'FandangoNow'), ('producerName', 'Paramount Pictures')]
# [('filmName', '"Crocodile" Dundee'), ('distributorName', 'Netflix'), ('producerName', 'Paramount Pictures')]
# [('filmName', '"Crocodile" Dundee II'), ('distributorName', 'FandangoNow'), ('producerName', 'Paramount Pictures')]
# [('filmName', '"Crocodile" Dundee II'), ('distributorName', 'Netflix'), ('producerName', 'Paramount Pictures')]
# [('filmName', '#1 Cheerleader Camp'), ('distributorName', 'Netflix'), ('producerName', 'The Asylum')]
# [('filmName', "'Neath the Arizona Skies"), ('distributorName', 'Monogram Pictures'), ('producerName', 'Lone Star Productions')]
# [('filmName', "'Neath the Arizona Skies"), ('distributorName', 'Netflix'), ('producerName', 'Lone Star Productions')]
# [('filmName', '-30-'), ('distributorName', 'Warner Bros.'), ('producerName', 'Mark VII Limited')]
# [('filmName', '...And Justice for All'), ('distributorName', 'Netflix'), ('producerName', 'Columbia Pictures')]
# [('filmName', '.hack//The Movie'), ('distributorName', 'Bandai Visual'), ('producerName', 'CyberConnect2')]
# [('filmName', '1, 2, 3, Sun'), ('distributorName', 'Netflix'), ('producerName', 'Gaumont Film Company')]
# [('filmName', '1-2-3 Corona'), ('distributorName', 'Progress Film'), ('producerName', 'DEFA')]
# [('filmName', '10'), ('distributorName', 'FandangoNow'), ('producerName', 'Orion Pictures')]
# [('filmName', '10'), ('distributorName', 'Netflix'), ('producerName', 'Orion Pictures')]
# [('filmName', '10'), ('distributorName', 'Warner Bros.'), ('producerName', 'Orion Pictures')]
# [('filmName', '10 Cloverfield Lane'), ('distributorName', 'FandangoNow'), ('producerName', 'Bad Robot Productions')]
# [('filmName', '10 Cloverfield Lane'), ('distributorName', 'FandangoNow'), ('producerName', 'Paramount Pictures')]
# [('filmName', '10 Cloverfield Lane'), ('distributorName', 'Netflix'), ('producerName', 'Bad Robot Productions')]
# [('filmName', '10 Cloverfield Lane'), ('distributorName', 'Netflix'), ('producerName', 'Paramount Pictures')]
# [('filmName', '10 Cloverfield Lane'), ('distributorName', 'Paramount Pictures'), ('producerName', 'Bad Robot Productions')]
# [('filmName', '10 Cloverfield Lane'), ('distributorName', 'UIP-Dunafilm'), ('producerName', 'Bad Robot Productions')]
# [('filmName', '10 Cloverfield Lane'), ('distributorName', 'UIP-Dunafilm'), ('producerName', 'Paramount Pictures')]
# [('filmName', '10 Cloverfield Lane'), ('distributorName', 'Vudu'), ('producerName', 'Bad Robot Productions')]
# [('filmName', '10 Cloverfield Lane'), ('distributorName', 'Vudu'), ('producerName', 'Paramount Pictures')]
# [('filmName', '10 Items or Less'), ('distributorName', 'Netflix'), ('producerName', 'Revelations Entertainment')]
# [('filmName', '10 Items or Less'), ('distributorName', 'Netflix'), ('producerName', 'THINKFilm')]
# [('filmName', '10 Items or Less'), ('distributorName', 'THINKFilm'), ('producerName', 'Revelations Entertainment')]
# [('filmName', '10 Rillington Place'), ('distributorName', 'Columbia Pictures'), ('producerName', 'Filmways')]
# [('filmName', '10 Rillington Place'), ('distributorName', 'FandangoNow'), ('producerName', 'Filmways')]
# [('filmName', '10 Rillington Place'), ('distributorName', 'Netflix'), ('producerName', 'Filmways')]
# [('filmName', '10 Things I Hate About You'), ('distributorName', 'Disney+'), ('producerName', 'Touchstone Pictures')]
# [('filmName', '10 Things I Hate About You'), ('distributorName', 'FandangoNow'), ('producerName', 'Touchstone Pictures')]
# [('filmName', '10 Things I Hate About You'), ('distributorName', 'InterCom'), ('producerName', 'Touchstone Pictures')]
# [('filmName', '10 Things I Hate About You'), ('distributorName', 'Netflix'), ('producerName', 'Touchstone Pictures')]
# [('filmName', '10 Years'), ('distributorName', 'ADS Service'), ('producerName', 'Temple Hill Entertainment')]
# [('filmName', '10 Years'), ('distributorName', 'Anchor Bay Entertainment'), ('producerName', 'Temple Hill Entertainment')]
# [('filmName', '10 Years'), ('distributorName', 'Hulu'), ('producerName', 'Temple Hill Entertainment')]
# [('filmName', '10 Years'), ('distributorName', 'Netflix'), ('producerName', 'Temple Hill Entertainment')]
# [('filmName', '10 to Midnight'), ('distributorName', 'Netflix'), ('producerName', 'The Cannon Group')]
# [('filmName', '10,000 BC'), ('distributorName', 'FandangoNow'), ('producerName', 'Centropolis Entertainment')]
# [('filmName', '10,000 BC'), ('distributorName', 'FandangoNow'), ('producerName', 'Legendary Pictures')]
# [('filmName', '10,000 BC'), ('distributorName', 'InterCom'), ('producerName', 'Centropolis Entertainment')]
# [('filmName', '10,000 BC'), ('distributorName', 'InterCom'), ('producerName', 'Legendary Pictures')]
# [('filmName', '10,000 BC'), ('distributorName', 'Netflix'), ('producerName', 'Centropolis Entertainment')]
# [('filmName', '10,000 BC'), ('distributorName', 'Netflix'), ('producerName', 'Legendary Pictures')]
# [('filmName', '10,000 km'), ('distributorName', 'Broad Green Pictures'), ('producerName', 'La Panda Productions')]
# [('filmName', '10,000 km'), ('distributorName', 'Broad Green Pictures'), ('producerName', 'TV3')]
# [('filmName', '10,000 km'), ('distributorName', 'Broad Green Pictures'), ('producerName', 'Televisión Española')]
# [('filmName', '10,000 km'), ('distributorName', 'Cirko Film'), ('producerName', 'La Panda Productions')]
# [('filmName', '10,000 km'), ('distributorName', 'Cirko Film'), ('producerName', 'TV3')]
# 50

# %%
#Now I get only the companies that are television production company and film production company
queryString = """
SELECT DISTINCT ?filmName ?distributorName ?producerName
WHERE {

   # bind something
   # ?film wdt:P31 wd:Q11424.
   # ?film wdt:P750 ?distributor.
   
   # ?distributor wdt:P31 ?disType. #I get the instances of the distributor .
   
   # ?film wdt:P272 ?producer .
   # ?producer wdt:P31 ?proType . #I get the instances of the producers .
   
                   #Television production company    #film production company 
   VALUES ?disType {wd:Q10689397                    wd:Q1762059} 
   VALUES ?proType {wd:Q10689397                    wd:Q1762059}
   
   
   FILTER (?distributor != ?producer) #The values of the producer and the distributor can't be the same. 
   
   
   # get the label
   # ?film sc:name ?filmName.
    # ?distributor sc:name ?distributorName .
    # ?producer sc:name ?producerName .
}
ORDER BY ?filmName ?distributorName ?producerName
LIMIT 50
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('filmName', '"Crocodile" Dundee'), ('distributorName', 'Netflix'), ('producerName', 'Paramount Pictures')]
# [('filmName', '"Crocodile" Dundee II'), ('distributorName', 'Netflix'), ('producerName', 'Paramount Pictures')]
# [('filmName', '#1 Cheerleader Camp'), ('distributorName', 'Netflix'), ('producerName', 'The Asylum')]
# [('filmName', '...And Justice for All'), ('distributorName', 'Netflix'), ('producerName', 'Columbia Pictures')]
# [('filmName', '1, 2, 3, Sun'), ('distributorName', 'Netflix'), ('producerName', 'Gaumont Film Company')]
# [('filmName', '10'), ('distributorName', 'Netflix'), ('producerName', 'Orion Pictures')]
# [('filmName', '10'), ('distributorName', 'Warner Bros.'), ('producerName', 'Orion Pictures')]
# [('filmName', '10 Cloverfield Lane'), ('distributorName', 'Netflix'), ('producerName', 'Bad Robot Productions')]
# [('filmName', '10 Cloverfield Lane'), ('distributorName', 'Netflix'), ('producerName', 'Paramount Pictures')]
# [('filmName', '10 Cloverfield Lane'), ('distributorName', 'Paramount Pictures'), ('producerName', 'Bad Robot Productions')]
# [('filmName', '10 Items or Less'), ('distributorName', 'Netflix'), ('producerName', 'THINKFilm')]
# [('filmName', '10 Rillington Place'), ('distributorName', 'Columbia Pictures'), ('producerName', 'Filmways')]
# [('filmName', '10 Rillington Place'), ('distributorName', 'Netflix'), ('producerName', 'Filmways')]
# [('filmName', '10 Things I Hate About You'), ('distributorName', 'Netflix'), ('producerName', 'Touchstone Pictures')]
# [('filmName', '10 Years'), ('distributorName', 'Anchor Bay Entertainment'), ('producerName', 'Temple Hill Entertainment')]
# [('filmName', '10 Years'), ('distributorName', 'Netflix'), ('producerName', 'Temple Hill Entertainment')]
# [('filmName', '10 to Midnight'), ('distributorName', 'Netflix'), ('producerName', 'The Cannon Group')]
# [('filmName', '10,000 BC'), ('distributorName', 'Netflix'), ('producerName', 'Legendary Pictures')]
# [('filmName', '10,000 km'), ('distributorName', 'Broad Green Pictures'), ('producerName', 'La Panda Productions')]
# [('filmName', '100 Feet'), ('distributorName', 'Netflix'), ('producerName', 'The Asylum')]
# [('filmName', '100 Ghost Street: The Return of Richard Speck'), ('distributorName', 'Netflix'), ('producerName', 'The Asylum')]
# [('filmName', '100 Rifles'), ('distributorName', 'Netflix'), ('producerName', '20th Century Studios')]
# [('filmName', '1001 Arabian Nights'), ('distributorName', 'Columbia Pictures'), ('producerName', 'UPA')]
# [('filmName', '101 Reykjavík'), ('distributorName', 'Netflix'), ('producerName', 'Zentropa')]
# [('filmName', '102 Not Out'), ('distributorName', 'Columbia Pictures'), ('producerName', 'Sony Pictures')]
# [('filmName', '11:14'), ('distributorName', 'Netflix'), ('producerName', 'Media 8 Entertainment')]
# [('filmName', '11:14'), ('distributorName', 'New Line Cinema'), ('producerName', 'Media 8 Entertainment')]
# [('filmName', '12 Monkeys'), ('distributorName', 'Netflix'), ('producerName', 'Universal Pictures')]
# [('filmName', '12 Rounds'), ('distributorName', '20th Century Studios'), ('producerName', 'WWE Studios')]
# [('filmName', '12 Rounds'), ('distributorName', 'Netflix'), ('producerName', 'WWE Studios')]
# [('filmName', '12 Years a Slave'), ('distributorName', 'Netflix'), ('producerName', 'Film4 Productions')]
# [('filmName', '12 Years a Slave'), ('distributorName', 'Netflix'), ('producerName', 'Plan B Entertainment')]
# [('filmName', '12 Years a Slave'), ('distributorName', 'Netflix'), ('producerName', 'Regency Enterprises')]
# [('filmName', '12 Years a Slave'), ('distributorName', 'Netflix'), ('producerName', 'Summit Entertainment')]
# [('filmName', '12/12/12'), ('distributorName', 'Netflix'), ('producerName', 'The Asylum')]
# [('filmName', '127 Hours'), ('distributorName', 'Netflix'), ('producerName', 'Pathé')]
# [('filmName', '127 Hours'), ('distributorName', 'Netflix'), ('producerName', 'Searchlight Pictures')]
# [('filmName', '127 Hours'), ('distributorName', 'Searchlight Pictures'), ('producerName', 'Pathé')]
# [('filmName', '12:01'), ('distributorName', 'Fox Broadcasting Company'), ('producerName', 'New Line Cinema')]
# [('filmName', '12:01'), ('distributorName', 'Netflix'), ('producerName', 'New Line Cinema')]
# [('filmName', '13'), ('distributorName', 'Anchor Bay Entertainment'), ('producerName', 'Paramount Vantage')]
# [('filmName', '13'), ('distributorName', 'Netflix'), ('producerName', 'Paramount Vantage')]
# [('filmName', '13 Hours: The Secret Soldiers of Benghazi'), ('distributorName', 'Netflix'), ('producerName', 'Paramount Pictures')]
# [('filmName', '13 Lead Soldiers'), ('distributorName', '20th Century Studios'), ('producerName', 'Edward Small Productions')]
# [('filmName', '13 Rue Madeleine'), ('distributorName', 'Netflix'), ('producerName', '20th Century Studios')]
# [('filmName', '13 Sins'), ('distributorName', 'Netflix'), ('producerName', 'Dimension Films')]
# [('filmName', '13/13/13'), ('distributorName', 'Netflix'), ('producerName', 'The Asylum')]
# [('filmName', '1492 – Conquest of Paradise'), ('distributorName', 'Netflix'), ('producerName', 'Gaumont Film Company')]
# [('filmName', '1492 – Conquest of Paradise'), ('distributorName', 'Netflix'), ('producerName', 'Légende Entreprises')]
# [('filmName', '1492 – Conquest of Paradise'), ('distributorName', 'Paramount Pictures'), ('producerName', 'Gaumont Film Company')]
# 50

# %% [markdown]
# Final query for this task

# %%
#The last thing to do its to get the number of films for each distributor and only show the one with more films. 

queryString = """
SELECT DISTINCT ?distributor ?distributorName (COUNT(*) AS ?films)
WHERE {

   # bind something
   # ?film wdt:P31 wd:Q11424.
   # ?film wdt:P750 ?distributor.
   
   # ?distributor wdt:P31 ?disType. #I get the instances of the distributor .
   
   # ?film wdt:P272 ?producer .
   # ?producer wdt:P31 ?proType . #I get the instances of the producers .
   
                   #Television production company    #film production company 
   VALUES ?disType {wd:Q10689397                    wd:Q1762059} 
   VALUES ?proType {wd:Q10689397                    wd:Q1762059}
   
   
   FILTER (?distributor != ?producer) #The values of the producer and the distributor can't be the same. 
   
   
   # get the label
   # ?film sc:name ?filmName.
    # ?distributor sc:name ?distributorName .
    # ?producer sc:name ?producerName .
}
ORDER BY DESC (?films) 
LIMIT 1
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('distributor', 'http://www.wikidata.org/entity/Q907311'), ('distributorName', 'Netflix'), ('films', '10756')]
# 1

# %% [markdown]
# ## Task 7
# Find how many company are listed in every stock exchange market (the result set must be a list of triples stock exchange IRI, label and #companies).

# %%
#I need the identifier for company. I am going to search for the instances of production company 
queryString = """
SELECT DISTINCT ?inst ?iname 
WHERE {
   # bind something
   wd:Q1762059 ?p ?obj .
   # ?obj wdt:P279 ?inst.
   
   # get the label
   # ?inst sc:name ?iname.
}
ORDER BY ?iname
LIMIT 200
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('inst', 'http://www.wikidata.org/entity/Q20897549'), ('iname', 'art institution')]
# [('inst', 'http://www.wikidata.org/entity/Q783794'), ('iname', 'company')]
# [('inst', 'http://www.wikidata.org/entity/Q3152824'), ('iname', 'cultural institution')]
# [('inst', 'http://www.wikidata.org/entity/Q19595701'), ('iname', 'entertainment industry')]
# [('inst', 'http://www.wikidata.org/entity/Q104649845'), ('iname', 'film organization')]
# [('inst', 'http://www.wikidata.org/entity/Q1331793'), ('iname', 'media company')]
# [('inst', 'http://www.wikidata.org/entity/Q19364326'), ('iname', 'media studio facility')]
# 7

# %%
#Lets find that property on the properties of the companies. Lets start with the properties of netflix. 
queryString = """
SELECT DISTINCT ?p ?name
WHERE {
   # bind something
   wd:Q907311 ?p ?obj .
   # get the label
   # ?p sc:name ?name.
}
ORDER BY DESC (?name)
LIMIT 500
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P2283'), ('name', 'uses')]
# [('p', 'http://www.wikidata.org/prop/direct/P2139'), ('name', 'total revenue')]
# [('p', 'http://www.wikidata.org/prop/direct/P2403'), ('name', 'total assets')]
# [('p', 'http://www.wikidata.org/prop/direct/P1424'), ('name', "topic's main template")]
# [('p', 'http://www.wikidata.org/prop/direct/P910'), ('name', "topic's main category")]
# [('p', 'http://www.wikidata.org/prop/direct/P355'), ('name', 'subsidiary')]
# [('p', 'http://www.wikidata.org/prop/direct/P3984'), ('name', 'subreddit')]
# [('p', 'http://www.wikidata.org/prop/direct/P414'), ('name', 'stock exchange')]
# [('p', 'http://www.wikidata.org/prop/direct/P8687'), ('name', 'social media followers')]
# [('p', 'http://www.wikidata.org/prop/direct/P9138'), ('name', 'service status information URL')]
# [('p', 'http://www.wikidata.org/prop/direct/P4354'), ('name', 'search formatter URL')]
# [('p', 'http://www.wikidata.org/prop/direct/P1056'), ('name', 'product or material produced')]
# [('p', 'http://www.wikidata.org/prop/direct/P400'), ('name', 'platform')]
# [('p', 'http://www.wikidata.org/prop/direct/P361'), ('name', 'part of')]
# [('p', 'http://www.wikidata.org/prop/direct/P127'), ('name', 'owned by')]
# [('p', 'http://www.wikidata.org/prop/direct/P3362'), ('name', 'operating income')]
# [('p', 'http://www.wikidata.org/prop/direct/P6954'), ('name', 'online access status')]
# [('p', 'http://www.wikidata.org/prop/direct/P856'), ('name', 'official website')]
# [('p', 'http://www.wikidata.org/prop/direct/P1581'), ('name', 'official blog')]
# [('p', 'http://www.wikidata.org/prop/direct/P1833'), ('name', 'number of registered users/contributors')]
# [('p', 'http://www.wikidata.org/prop/direct/P1411'), ('name', 'nominated for')]
# [('p', 'http://www.wikidata.org/prop/direct/P2295'), ('name', 'net profit')]
# [('p', 'http://www.wikidata.org/prop/direct/P463'), ('name', 'member of')]
# [('p', 'http://www.wikidata.org/prop/direct/P154'), ('name', 'logo image')]
# [('p', 'http://www.wikidata.org/prop/direct/P740'), ('name', 'location of formation')]
# [('p', 'http://www.wikidata.org/prop/direct/P1454'), ('name', 'legal form')]
# [('p', 'http://www.wikidata.org/prop/direct/P407'), ('name', 'language of work or name')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('name', 'instance of')]
# [('p', 'http://www.wikidata.org/prop/direct/P452'), ('name', 'industry')]
# [('p', 'http://www.wikidata.org/prop/direct/P571'), ('name', 'inception')]
# [('p', 'http://www.wikidata.org/prop/direct/P18'), ('name', 'image')]
# [('p', 'http://www.wikidata.org/prop/direct/P159'), ('name', 'headquarters location')]
# [('p', 'http://www.wikidata.org/prop/direct/P2572'), ('name', 'hashtag')]
# [('p', 'http://www.wikidata.org/prop/direct/P112'), ('name', 'founded by')]
# [('p', 'http://www.wikidata.org/prop/direct/P1128'), ('name', 'employees')]
# [('p', 'http://www.wikidata.org/prop/direct/P1846'), ('name', 'distribution map')]
# [('p', 'http://www.wikidata.org/prop/direct/P973'), ('name', 'described at URL')]
# [('p', 'http://www.wikidata.org/prop/direct/P17'), ('name', 'country')]
# [('p', 'http://www.wikidata.org/prop/direct/P169'), ('name', 'chief executive officer')]
# [('p', 'http://www.wikidata.org/prop/direct/P166'), ('name', 'award received')]
# [('p', 'http://www.wikidata.org/prop/direct/P3797'), ('name', 'autonomous system number')]
# [('p', 'http://www.wikidata.org/prop/direct/P3553'), ('name', 'Zhihu topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2397'), ('name', 'YouTube channel ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7859'), ('name', 'WorldCat Identities ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1687'), ('name', 'Wikidata property')]
# [('p', 'http://www.wikidata.org/prop/direct/P214'), ('name', 'VIAF ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P4527'), ('name', 'UK Parliament thesaurus ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2002'), ('name', 'Twitter username')]
# [('p', 'http://www.wikidata.org/prop/direct/P7085'), ('name', 'TikTok username')]
# [('p', 'http://www.wikidata.org/prop/direct/P7157'), ('name', 'The Top Tens ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6839'), ('name', 'TV Tropes identifier')]
# [('p', 'http://www.wikidata.org/prop/direct/P4342'), ('name', 'Store norske leksikon ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3242'), ('name', 'SIC code')]
# [('p', 'http://www.wikidata.org/prop/direct/P6782'), ('name', 'ROR ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3417'), ('name', 'Quora topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3836'), ('name', 'Pinterest username')]
# [('p', 'http://www.wikidata.org/prop/direct/P7771'), ('name', 'PersonalData.IO ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6900'), ('name', 'NicoNicoPedia ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P691'), ('name', 'NKCR AUT ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3222'), ('name', 'NE.se ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P966'), ('name', 'MusicBrainz label ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6366'), ('name', 'Microsoft Academic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P4776'), ('name', 'MAC Address Block Large ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P4264'), ('name', 'LinkedIn company ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P244'), ('name', 'Library of Congress authority ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6760'), ('name', 'Know Your Meme ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2003'), ('name', 'Instagram username')]
# [('p', 'http://www.wikidata.org/prop/direct/P946'), ('name', 'ISIN')]
# [('p', 'http://www.wikidata.org/prop/direct/P6869'), ('name', 'Hoopla publisher ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3106'), ('name', 'Guardian topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8939'), ('name', 'Google Play developer slug')]
# [('p', 'http://www.wikidata.org/prop/direct/P3418'), ('name', 'Google Play Store app ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7502'), ('name', 'Golden ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2037'), ('name', 'GitHub username')]
# [('p', 'http://www.wikidata.org/prop/direct/P9100'), ('name', 'GitHub topic')]
# [('p', 'http://www.wikidata.org/prop/direct/P4013'), ('name', 'Giphy username')]
# [('p', 'http://www.wikidata.org/prop/direct/P7997'), ('name', 'GRY-Online company ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2427'), ('name', 'GRID ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P227'), ('name', 'GND ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7818'), ('name', 'French Vikidia ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P646'), ('name', 'Freebase ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P9346'), ('name', 'France24 topic ID (French)')]
# [('p', 'http://www.wikidata.org/prop/direct/P4073'), ('name', 'Fandom wiki ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6262'), ('name', 'Fandom article ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2013'), ('name', 'Facebook ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1417'), ('name', 'Encyclopædia Britannica Online ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5576'), ('name', 'EDb company ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7306'), ('name', 'Downdetector ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6181'), ('name', 'Disney A to Z ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6849'), ('name', 'DR topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2088'), ('name', 'Crunchbase organization ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P373'), ('name', 'Commons category')]
# [('p', 'http://www.wikidata.org/prop/direct/P5531'), ('name', 'Central Index Key')]
# [('p', 'http://www.wikidata.org/prop/direct/P5019'), ('name', 'Brockhaus Enzyklopädie online ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2531'), ('name', 'Box Office Mojo studio ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P268'), ('name', 'Bibliothèque nationale de France ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3861'), ('name', 'App Store app ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P9618'), ('name', 'AlternativeTo software ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1661'), ('name', 'Alexa rank')]
# 99

# %%
#Now I get the values on the propertie stock exchange.  
queryString = """
SELECT DISTINCT ?inst ?iname 
WHERE {
   # bind something
   wd:Q36479 ?p ?obj .
   # ?obj wdt:P414 ?inst.
   
   # get the label
   # ?inst sc:name ?iname.
}
ORDER BY ?iname
LIMIT 200
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('inst', 'http://www.wikidata.org/entity/Q82059'), ('iname', 'NASDAQ')]
# 1

# %%
#lets explore from who is instance of NASDAQ. 
queryString = """
SELECT DISTINCT ?inst ?iname 
WHERE {
   # bind something
   wd:Q82059 ?p ?obj .
   # ?obj wdt:P31 ?inst.
   
   # get the label
   # ?inst sc:name ?iname.
}
ORDER BY ?iname
LIMIT 200
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('inst', 'http://www.wikidata.org/entity/Q202686'), ('iname', 'Commonwealth realm')]
# [('inst', 'http://www.wikidata.org/entity/Q4167836'), ('iname', 'Wikimedia category')]
# [('inst', 'http://www.wikidata.org/entity/Q11266439'), ('iname', 'Wikimedia template')]
# [('inst', 'http://www.wikidata.org/entity/Q1549591'), ('iname', 'big city')]
# [('inst', 'http://www.wikidata.org/entity/Q4830453'), ('iname', 'business')]
# [('inst', 'http://www.wikidata.org/entity/Q5119'), ('iname', 'capital')]
# [('inst', 'http://www.wikidata.org/entity/Q515'), ('iname', 'city')]
# [('inst', 'http://www.wikidata.org/entity/Q6256'), ('iname', 'country')]
# [('inst', 'http://www.wikidata.org/entity/Q8142'), ('iname', 'currency')]
# [('inst', 'http://www.wikidata.org/entity/Q28795800'), ('iname', 'decimal currency')]
# [('inst', 'http://www.wikidata.org/entity/Q14083'), ('iname', 'dollar')]
# [('inst', 'http://www.wikidata.org/entity/Q223832'), ('iname', 'dominion of the British Empire')]
# [('inst', 'http://www.wikidata.org/entity/Q8187769'), ('iname', 'economic activity')]
# [('inst', 'http://www.wikidata.org/entity/Q6881511'), ('iname', 'enterprise')]
# [('inst', 'http://www.wikidata.org/entity/Q43702'), ('iname', 'federation')]
# [('inst', 'http://www.wikidata.org/entity/Q2298435'), ('iname', 'futures exchange')]
# [('inst', 'http://www.wikidata.org/entity/Q5'), ('iname', 'human')]
# [('inst', 'http://www.wikidata.org/entity/Q2135465'), ('iname', 'legal concept')]
# [('inst', 'http://www.wikidata.org/entity/Q12047392'), ('iname', 'legal form')]
# [('inst', 'http://www.wikidata.org/entity/Q200250'), ('iname', 'metropolis')]
# [('inst', 'http://www.wikidata.org/entity/Q1637706'), ('iname', 'million city')]
# [('inst', 'http://www.wikidata.org/entity/Q891723'), ('iname', 'public company')]
# [('inst', 'http://www.wikidata.org/entity/Q3624078'), ('iname', 'sovereign state')]
# [('inst', 'http://www.wikidata.org/entity/Q11691'), ('iname', 'stock exchange')]
# [('inst', 'http://www.wikidata.org/entity/Q1269299'), ('iname', 'type of business entity')]
# [('inst', 'http://www.wikidata.org/entity/Q17197366'), ('iname', 'type of organisation')]
# 26

# %%
#I get all the companies that have the property stock exchange and show also the stock exchange that the are in . Company  (Q783794)
queryString = """

SELECT DISTINCT ?company ?companyName ?stock ?stockName
WHERE {

   #bind something
   # ?company wdt:P31 wd:Q783794 .
   # ?company wdt:P414 ?stock .
   
   # get the label 
   # ?company sc:name ?companyName .
   # ?stock sc:name ?stockName .
}
ORDER BY ?stockName ?companyName
LIMIT 5
#LIMIT 1000 #I coment this limit to don't get the page to long but with that limit you can see all the companies on the NASDAQ and Netflix is not
            #in that so we don't want this result due to that doesn't provides me all the companies for what probably don't provides neither all 
            #the stock exchange markets. 

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('company', 'http://www.wikidata.org/entity/Q30153680'), ('companyName', 'Orion Land'), ('stock', 'http://www.wikidata.org/entity/Q438511'), ('stockName', 'Alternative Investment Market')]
# [('company', 'http://www.wikidata.org/entity/Q104839317'), ('companyName', '1300 SMILES'), ('stock', 'http://www.wikidata.org/entity/Q732670'), ('stockName', 'Australian Securities Exchange')]
# [('company', 'http://www.wikidata.org/entity/Q20311412'), ('companyName', 'APA Group'), ('stock', 'http://www.wikidata.org/entity/Q732670'), ('stockName', 'Australian Securities Exchange')]
# [('company', 'http://www.wikidata.org/entity/Q55639119'), ('companyName', 'Afterpay'), ('stock', 'http://www.wikidata.org/entity/Q732670'), ('stockName', 'Australian Securities Exchange')]
# [('company', 'http://www.wikidata.org/entity/Q67174463'), ('companyName', 'AppsVillage'), ('stock', 'http://www.wikidata.org/entity/Q732670'), ('stockName', 'Australian Securities Exchange')]
# 5

# %% [markdown]
# I don't find Netflix among the NASDAQ stock exchange, so with the last query I don't get all the companies, I look to find all that have the property stock exchange(P414) insted

# %%
#I get all the companies and the stock market that they are. 
queryString = """

SELECT DISTINCT ?company ?companyName ?stock ?stockName
WHERE {

   #bind something
   # ?company wdt:P414 ?stock.
   
   # get the label 
   # ?company sc:name ?companyName .
   # ?stock sc:name ?stockName .
}
ORDER BY ?stockName ?companyName 
LIMIT 5
#LIMIT 5000 #This limit I comment it due to I put it to high to see if finally I got all the companies and it seems so.

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('company', 'http://www.wikidata.org/entity/Q4819798'), ('companyName', 'AudioBoom'), ('stock', 'http://www.wikidata.org/entity/Q438511'), ('stockName', 'Alternative Investment Market')]
# [('company', 'http://www.wikidata.org/entity/Q17070435'), ('companyName', 'Beowulf Mining'), ('stock', 'http://www.wikidata.org/entity/Q438511'), ('stockName', 'Alternative Investment Market')]
# [('company', 'http://www.wikidata.org/entity/Q17008542'), ('companyName', 'Datatec'), ('stock', 'http://www.wikidata.org/entity/Q438511'), ('stockName', 'Alternative Investment Market')]
# [('company', 'http://www.wikidata.org/entity/Q50390569'), ('companyName', 'European Metals Holdings'), ('stock', 'http://www.wikidata.org/entity/Q438511'), ('stockName', 'Alternative Investment Market')]
# [('company', 'http://www.wikidata.org/entity/Q16984856'), ('companyName', 'Horizon Discovery'), ('stock', 'http://www.wikidata.org/entity/Q438511'), ('stockName', 'Alternative Investment Market')]
# 5

# %% [markdown]
# Final query for this task

# %%
#I remove the companies and look only the stock and then count all the companies
queryString = """

SELECT DISTINCT  ?stock ?stockName (COUNT(*) AS ?companies)
WHERE {

   #bind something
   # ?company wdt:P414 ?stock.
   
   # get the label 
   
   # ?stock sc:name ?stockName .
}
ORDER BY ?stockName  
LIMIT 200


"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('stock', 'http://www.wikidata.org/entity/Q438511'), ('stockName', 'Alternative Investment Market'), ('companies', '8')]
# [('stock', 'http://www.wikidata.org/entity/Q11285412'), ('stockName', 'Ambitious'), ('companies', '1')]
# [('stock', 'http://www.wikidata.org/entity/Q463881'), ('stockName', 'American depositary receipt'), ('companies', '1')]
# [('stock', 'http://www.wikidata.org/entity/Q74039053'), ('stockName', 'Amsterdam Stock Exchange'), ('companies', '1')]
# [('stock', 'http://www.wikidata.org/entity/Q683787'), ('stockName', 'Armenia Securities Exchange'), ('companies', '2')]
# [('stock', 'http://www.wikidata.org/entity/Q755341'), ('stockName', 'Athens Exchange'), ('companies', '13')]
# [('stock', 'http://www.wikidata.org/entity/Q732670'), ('stockName', 'Australian Securities Exchange'), ('companies', '146')]
# [('stock', 'http://www.wikidata.org/entity/Q12721279'), ('stockName', 'Australian Stock Exchange'), ('companies', '2')]
# [('stock', 'http://www.wikidata.org/entity/Q796297'), ('stockName', 'B3'), ('companies', '156')]
# [('stock', 'http://www.wikidata.org/entity/Q795469'), ('stockName', 'BATS Global Markets'), ('companies', '1')]
# [('stock', 'http://www.wikidata.org/entity/Q795840'), ('stockName', 'BET-10'), ('companies', '1')]
# [('stock', 'http://www.wikidata.org/entity/Q1019978'), ('stockName', 'BOERSE DUESSELDORF'), ('companies', '1')]
# [('stock', 'http://www.wikidata.org/entity/Q550050'), ('stockName', 'Belgrade Stock Exchange'), ('companies', '2')]
# [('stock', 'http://www.wikidata.org/entity/Q571760'), ('stockName', 'Berliner Börse'), ('companies', '1')]
# [('stock', 'http://www.wikidata.org/entity/Q2382352'), ('stockName', 'Bermuda Stock Exchange'), ('companies', '3')]
# [('stock', 'http://www.wikidata.org/entity/Q4890307'), ('stockName', 'Bilbao Stock Exchange'), ('companies', '1')]
# [('stock', 'http://www.wikidata.org/entity/Q51403327'), ('stockName', 'Binance'), ('companies', '8')]
# [('stock', 'http://www.wikidata.org/entity/Q104786134'), ('stockName', 'BitBay'), ('companies', '1')]
# [('stock', 'http://www.wikidata.org/entity/Q29647473'), ('stockName', 'Bitfinex'), ('companies', '4')]
# [('stock', 'http://www.wikidata.org/entity/Q617426'), ('stockName', 'Bolsa de Madrid'), ('companies', '32')]
# [('stock', 'http://www.wikidata.org/entity/Q4202960'), ('stockName', 'Bolsa de Valores de Barcelona'), ('companies', '3')]
# [('stock', 'http://www.wikidata.org/entity/Q8250595'), ('stockName', 'Bolsa de Valores y Productos de Asunción'), ('companies', '1')]
# [('stock', 'http://www.wikidata.org/entity/Q609159'), ('stockName', 'Bolsas y Mercados Españoles'), ('companies', '2')]
# [('stock', 'http://www.wikidata.org/entity/Q638398'), ('stockName', 'Bombay Stock Exchange'), ('companies', '35')]
# [('stock', 'http://www.wikidata.org/entity/Q1407995'), ('stockName', 'Borsa Istanbul'), ('companies', '6')]
# [('stock', 'http://www.wikidata.org/entity/Q74603'), ('stockName', 'Bratislava Stock Exchange'), ('companies', '3')]
# [('stock', 'http://www.wikidata.org/entity/Q1003245'), ('stockName', 'Bucharest Stock Exchange'), ('companies', '2')]
# [('stock', 'http://www.wikidata.org/entity/Q851259'), ('stockName', 'Budapest Stock Exchange'), ('companies', '9')]
# [('stock', 'http://www.wikidata.org/entity/Q891560'), ('stockName', 'Buenos Aires Stock Exchange'), ('companies', '6')]
# [('stock', 'http://www.wikidata.org/entity/Q1003968'), ('stockName', 'Bulgarian Stock Exchange'), ('companies', '3')]
# [('stock', 'http://www.wikidata.org/entity/Q43335'), ('stockName', 'Bursa Malaysia'), ('companies', '7')]
# [('stock', 'http://www.wikidata.org/entity/Q681683'), ('stockName', 'Börse München'), ('companies', '1')]
# [('stock', 'http://www.wikidata.org/entity/Q1022714'), ('stockName', 'CAC Small'), ('companies', '1')]
# [('stock', 'http://www.wikidata.org/entity/Q22907145'), ('stockName', 'CEX.io'), ('companies', '1')]
# [('stock', 'http://www.wikidata.org/entity/Q2602796'), ('stockName', 'Casablanca Stock Exchange'), ('companies', '1')]
# [('stock', 'http://www.wikidata.org/entity/Q2633007'), ('stockName', 'Chicago Stock Exchange'), ('companies', '3')]
# [('stock', 'http://www.wikidata.org/entity/Q3349831'), ('stockName', 'Chittagong Stock Exchange'), ('companies', '2')]
# [('stock', 'http://www.wikidata.org/entity/Q56251056'), ('stockName', 'CoinMarketCap'), ('companies', '1')]
# [('stock', 'http://www.wikidata.org/entity/Q16972754'), ('stockName', 'Coinbase'), ('companies', '5')]
# [('stock', 'http://www.wikidata.org/entity/Q2888321'), ('stockName', 'Cyprus Stock Exchange'), ('companies', '1')]
# [('stock', 'http://www.wikidata.org/entity/Q490028'), ('stockName', 'Dar es Salaam Stock Exchange'), ('companies', '1')]
# [('stock', 'http://www.wikidata.org/entity/Q157852'), ('stockName', 'Deutsche Börse'), ('companies', '3')]
# [('stock', 'http://www.wikidata.org/entity/Q1974408'), ('stockName', 'Dhaka Stock Exchange'), ('companies', '4')]
# [('stock', 'http://www.wikidata.org/entity/Q1973019'), ('stockName', 'Dubai Financial Market'), ('companies', '1')]
# [('stock', 'http://www.wikidata.org/entity/Q2509254'), ('stockName', 'Egyptian Exchange'), ('companies', '1')]
# [('stock', 'http://www.wikidata.org/entity/Q842108'), ('stockName', 'Euronext'), ('companies', '91')]
# [('stock', 'http://www.wikidata.org/entity/Q478720'), ('stockName', 'Euronext Amsterdam'), ('companies', '11')]
# [('stock', 'http://www.wikidata.org/entity/Q1146518'), ('stockName', 'Euronext Brussels'), ('companies', '6')]
# [('stock', 'http://www.wikidata.org/entity/Q144458'), ('stockName', 'Euronext Dublin'), ('companies', '9')]
# [('stock', 'http://www.wikidata.org/entity/Q2718247'), ('stockName', 'Euronext Growth'), ('companies', '2')]
# [('stock', 'http://www.wikidata.org/entity/Q2415561'), ('stockName', 'Euronext Lisbon'), ('companies', '7')]
# [('stock', 'http://www.wikidata.org/entity/Q12005867'), ('stockName', 'Euronext NOTC'), ('companies', '1')]
# [('stock', 'http://www.wikidata.org/entity/Q2385849'), ('stockName', 'Euronext Paris'), ('companies', '40')]
# [('stock', 'http://www.wikidata.org/entity/Q3737357'), ('stockName', 'FTSE Italia All-Share'), ('companies', '1')]
# [('stock', 'http://www.wikidata.org/entity/Q151139'), ('stockName', 'Frankfurt Stock Exchange'), ('companies', '97')]
# [('stock', 'http://www.wikidata.org/entity/Q5507703'), ('stockName', 'Fukuoka Stock Exchange'), ('companies', '20')]
# [('stock', 'http://www.wikidata.org/entity/Q74662'), ('stockName', 'Fundsquare Market Infrastructure'), ('companies', '7')]
# [('stock', 'http://www.wikidata.org/entity/Q97574837'), ('stockName', 'GDAX'), ('companies', '2')]
# [('stock', 'http://www.wikidata.org/entity/Q183'), ('stockName', 'Germany'), ('companies', '1')]
# [('stock', 'http://www.wikidata.org/entity/Q1521374'), ('stockName', 'Ghana Stock Exchange'), ('companies', '1')]
# [('stock', 'http://www.wikidata.org/entity/Q5566927'), ('stockName', 'Glasgow Stock Exchange'), ('companies', '1')]
# [('stock', 'http://www.wikidata.org/entity/Q558551'), ('stockName', 'Hamburg Stock Exchange'), ('companies', '1')]
# [('stock', 'http://www.wikidata.org/entity/Q97574930'), ('stockName', 'HitBTC'), ('companies', '1')]
# [('stock', 'http://www.wikidata.org/entity/Q751361'), ('stockName', 'Hong Kong Exchanges and Clearing Limited'), ('companies', '1')]
# [('stock', 'http://www.wikidata.org/entity/Q496672'), ('stockName', 'Hong Kong Stock Exchange'), ('companies', '1799')]
# [('stock', 'http://www.wikidata.org/entity/Q19892740'), ('stockName', 'Huobi'), ('companies', '2')]
# [('stock', 'http://www.wikidata.org/entity/Q938032'), ('stockName', 'IBEX 35'), ('companies', '1')]
# [('stock', 'http://www.wikidata.org/entity/Q16846407'), ('stockName', 'IEX'), ('companies', '1')]
# [('stock', 'http://www.wikidata.org/entity/Q1674303'), ('stockName', 'Iceland Stock Exchange'), ('companies', '1')]
# [('stock', 'http://www.wikidata.org/entity/Q291740'), ('stockName', 'Indice de Precios y Cotizaciones'), ('companies', '1')]
# [('stock', 'http://www.wikidata.org/entity/Q1661737'), ('stockName', 'Indonesia Stock Exchange'), ('companies', '697')]
# [('stock', 'http://www.wikidata.org/entity/Q1666934'), ('stockName', 'International Standard Industrial Classification'), ('companies', '1')]
# [('stock', 'http://www.wikidata.org/entity/Q1369913'), ('stockName', 'Iraq Stock Exchange'), ('companies', '1')]
# [('stock', 'http://www.wikidata.org/entity/Q936563'), ('stockName', 'Italian Bourse'), ('companies', '34')]
# [('stock', 'http://www.wikidata.org/entity/Q1683760'), ('stockName', 'JASDAQ Securities Exchange'), ('companies', '13')]
# [('stock', 'http://www.wikidata.org/entity/Q627514'), ('stockName', 'JSE Limited'), ('companies', '25')]
# [('stock', 'http://www.wikidata.org/entity/Q2573852'), ('stockName', 'Jakarta Stock Exchange'), ('companies', '1')]
# [('stock', 'http://www.wikidata.org/entity/Q491503'), ('stockName', 'KOSDAQ'), ('companies', '16')]
# [('stock', 'http://www.wikidata.org/entity/Q1977283'), ('stockName', 'Karachi Stock Exchange'), ('companies', '2')]
# [('stock', 'http://www.wikidata.org/entity/Q1734773'), ('stockName', 'Kazakhstan Stock Exchange'), ('companies', '8')]
# [('stock', 'http://www.wikidata.org/entity/Q495372'), ('stockName', 'Korea Exchange'), ('companies', '61')]
# [('stock', 'http://www.wikidata.org/entity/Q495364'), ('stockName', 'Korea Stock Exchange'), ('companies', '417')]
# [('stock', 'http://www.wikidata.org/entity/Q22906202'), ('stockName', 'Kraken'), ('companies', '2')]
# [('stock', 'http://www.wikidata.org/entity/Q97572932'), ('stockName', 'KuCoin Exchange'), ('companies', '1')]
# [('stock', 'http://www.wikidata.org/entity/Q4164626'), ('stockName', 'Kuwait Stock Exchange'), ('companies', '1')]
# [('stock', 'http://www.wikidata.org/entity/Q2380045'), ('stockName', 'Lima Stock Exchange'), ('companies', '2')]
# [('stock', 'http://www.wikidata.org/entity/Q171240'), ('stockName', 'London Stock Exchange'), ('companies', '604')]
# [('stock', 'http://www.wikidata.org/entity/Q2922440'), ('stockName', 'Malta Stock Exchange'), ('companies', '1')]
# [('stock', 'http://www.wikidata.org/entity/Q97175280'), ('stockName', 'MetaMask'), ('companies', '1')]
# [('stock', 'http://www.wikidata.org/entity/Q891559'), ('stockName', 'Mexican Stock Exchange'), ('companies', '9')]
# [('stock', 'http://www.wikidata.org/entity/Q490'), ('stockName', 'Milan'), ('companies', '2')]
# [('stock', 'http://www.wikidata.org/entity/Q4513926'), ('stockName', 'Montenegro Stock Exchange'), ('companies', '2')]
# [('stock', 'http://www.wikidata.org/entity/Q2632892'), ('stockName', 'Moscow Exchange'), ('companies', '128')]
# [('stock', 'http://www.wikidata.org/entity/Q1421543'), ('stockName', 'Moscow Interbank Currency Exchange'), ('companies', '1')]
# [('stock', 'http://www.wikidata.org/entity/Q11340130'), ('stockName', 'Mothers'), ('companies', '16')]
# [('stock', 'http://www.wikidata.org/entity/Q4117996'), ('stockName', 'Muscat Securities Market'), ('companies', '1')]
# [('stock', 'http://www.wikidata.org/entity/Q82059'), ('stockName', 'NASDAQ'), ('companies', '1755')]
# [('stock', 'http://www.wikidata.org/entity/Q69336177'), ('stockName', 'NASDAQ Global Select Market'), ('companies', '1')]
# [('stock', 'http://www.wikidata.org/entity/Q507306'), ('stockName', 'NASDAQ-100'), ('companies', '1')]
# [('stock', 'http://www.wikidata.org/entity/Q39052382'), ('stockName', 'NEO Exchange'), ('companies', '1')]
# [('stock', 'http://www.wikidata.org/entity/Q846626'), ('stockName', 'NYSE American'), ('companies', '8')]
# [('stock', 'http://www.wikidata.org/entity/Q13683'), ('stockName', 'NYSE Euronext'), ('companies', '2')]
# [('stock', 'http://www.wikidata.org/entity/Q1188840'), ('stockName', 'Nagoya Stock Exchange'), ('companies', '41')]
# [('stock', 'http://www.wikidata.org/entity/Q2384385'), ('stockName', 'Nairobi Securities Exchange'), ('companies', '1')]
# [('stock', 'http://www.wikidata.org/entity/Q1019983'), ('stockName', 'Nasdaq Copenhagen'), ('companies', '99')]
# [('stock', 'http://www.wikidata.org/entity/Q581755'), ('stockName', 'Nasdaq Helsinki'), ('companies', '58')]
# [('stock', 'http://www.wikidata.org/entity/Q1019992'), ('stockName', 'Nasdaq Stockholm'), ('companies', '49')]
# [('stock', 'http://www.wikidata.org/entity/Q1433248'), ('stockName', 'Nasdaq Tallinn'), ('companies', '3')]
# [('stock', 'http://www.wikidata.org/entity/Q23308122'), ('stockName', 'National Equities Exchange and Quotations'), ('companies', '1')]
# [('stock', 'http://www.wikidata.org/entity/Q638740'), ('stockName', 'National Stock Exchange of India'), ('companies', '141')]
# [('stock', 'http://www.wikidata.org/entity/Q6529599'), ('stockName', 'Nepal Stock Exchange'), ('companies', '346')]
# [('stock', 'http://www.wikidata.org/entity/Q13677'), ('stockName', 'New York Stock Exchange'), ('companies', '1832')]
# [('stock', 'http://www.wikidata.org/entity/Q627019'), ('stockName', 'New Zealand Exchange'), ('companies', '27')]
# [('stock', 'http://www.wikidata.org/entity/Q10855618'), ('stockName', 'NewConnect'), ('companies', '5')]
# [('stock', 'http://www.wikidata.org/entity/Q838766'), ('stockName', 'Nigerian Stock Exchange'), ('companies', '1')]
# [('stock', 'http://www.wikidata.org/entity/Q1132158'), ('stockName', 'OMX AB'), ('companies', '11')]
# [('stock', 'http://www.wikidata.org/entity/Q1391676'), ('stockName', 'OTC Bulletin Board'), ('companies', '3')]
# [('stock', 'http://www.wikidata.org/entity/Q1930860'), ('stockName', 'OTC Markets Group'), ('companies', '364')]
# [('stock', 'http://www.wikidata.org/entity/Q18355668'), ('stockName', 'OTCQX 30'), ('companies', '1')]
# [('stock', 'http://www.wikidata.org/entity/Q3557929'), ('stockName', 'Old Stock Exchange'), ('companies', '1')]
# [('stock', 'http://www.wikidata.org/entity/Q1320224'), ('stockName', 'Osaka Exchange'), ('companies', '7')]
# [('stock', 'http://www.wikidata.org/entity/Q17239431'), ('stockName', 'Osaka Stock Exchange'), ('companies', '2')]
# [('stock', 'http://www.wikidata.org/entity/Q909158'), ('stockName', 'Oslo Stock Exchange'), ('companies', '154')]
# [('stock', 'http://www.wikidata.org/entity/Q1984912'), ('stockName', 'PFTS Ukraine Stock Exchange'), ('companies', '11')]
# [('stock', 'http://www.wikidata.org/entity/Q1593991'), ('stockName', 'PFTS index'), ('companies', '2')]
# [('stock', 'http://www.wikidata.org/entity/Q4458741'), ('stockName', 'Pacific Exchange'), ('companies', '1')]
# [('stock', 'http://www.wikidata.org/entity/Q22907578'), ('stockName', 'Pakistan Stock Exchange'), ('companies', '3')]
# [('stock', 'http://www.wikidata.org/entity/Q4992224'), ('stockName', 'Palestine Exchange'), ('companies', '2')]
# [('stock', 'http://www.wikidata.org/entity/Q178513'), ('stockName', 'Paris Bourse'), ('companies', '3')]
# [('stock', 'http://www.wikidata.org/entity/Q1526647'), ('stockName', 'Philippine Stock Exchange'), ('companies', '5')]
# [('stock', 'http://www.wikidata.org/entity/Q1752646'), ('stockName', 'Prague Stock Exchange'), ('companies', '39')]
# [('stock', 'http://www.wikidata.org/entity/Q11240145'), ('stockName', 'Q-Board'), ('companies', '3')]
# [('stock', 'http://www.wikidata.org/entity/Q1648198'), ('stockName', 'Qatar Exchange'), ('companies', '1')]
# [('stock', 'http://www.wikidata.org/entity/Q12048417'), ('stockName', 'RM-SYSTÉM, česká burza cenných papírů'), ('companies', '7')]
# [('stock', 'http://www.wikidata.org/entity/Q1624698'), ('stockName', 'Riga Stock Exchange'), ('companies', '2')]
# [('stock', 'http://www.wikidata.org/entity/Q921581'), ('stockName', 'Russell 1000 Index'), ('companies', '1')]
# [('stock', 'http://www.wikidata.org/entity/Q1344438'), ('stockName', 'Russian Trading System'), ('companies', '13')]
# [('stock', 'http://www.wikidata.org/entity/Q7386994'), ('stockName', 'S&P 400'), ('companies', '1')]
# [('stock', 'http://www.wikidata.org/entity/Q242345'), ('stockName', 'S&P 500'), ('companies', '2')]
# [('stock', 'http://www.wikidata.org/entity/Q2204387'), ('stockName', 'S&P/ASX 50'), ('companies', '1')]
# [('stock', 'http://www.wikidata.org/entity/Q661834'), ('stockName', 'SIX Swiss Exchange'), ('companies', '40')]
# [('stock', 'http://www.wikidata.org/entity/Q2306284'), ('stockName', 'Saint Petersburg Stock Exchange'), ('companies', '1')]
# [('stock', 'http://www.wikidata.org/entity/Q891561'), ('stockName', 'Santiago Stock Exchange'), ('companies', '37')]
# [('stock', 'http://www.wikidata.org/entity/Q11093491'), ('stockName', 'Sapporo Securities Exchange'), ('companies', '23')]
# [('stock', 'http://www.wikidata.org/entity/Q739514'), ('stockName', 'Shanghai Stock Exchange'), ('companies', '356')]
# [('stock', 'http://www.wikidata.org/entity/Q517750'), ('stockName', 'Shenzhen Stock Exchange'), ('companies', '493')]
# [('stock', 'http://www.wikidata.org/entity/Q1515558'), ('stockName', 'Singapore Exchange'), ('companies', '12')]
# [('stock', 'http://www.wikidata.org/entity/Q93360933'), ('stockName', 'Spotlight Stock Market'), ('companies', '3')]
# [('stock', 'http://www.wikidata.org/entity/Q10404117'), ('stockName', 'Spotlight Stock Market'), ('companies', '1')]
# [('stock', 'http://www.wikidata.org/entity/Q3642744'), ('stockName', 'Stock Exchange in Milano'), ('companies', '8')]
# [('stock', 'http://www.wikidata.org/entity/Q4491713'), ('stockName', 'Stock Exchange of Mauritius'), ('companies', '1')]
# [('stock', 'http://www.wikidata.org/entity/Q1330208'), ('stockName', 'Stock Exchange of Thailand'), ('companies', '14')]
# [('stock', 'http://www.wikidata.org/entity/Q3117577'), ('stockName', 'TMX Group'), ('companies', '1')]
# [('stock', 'http://www.wikidata.org/entity/Q7671764'), ('stockName', 'TSX Venture Exchange'), ('companies', '1')]
# [('stock', 'http://www.wikidata.org/entity/Q2006583'), ('stockName', 'Tadawul'), ('companies', '180')]
# [('stock', 'http://www.wikidata.org/entity/Q5598539'), ('stockName', 'Taipei Exchange'), ('companies', '8')]
# [('stock', 'http://www.wikidata.org/entity/Q548621'), ('stockName', 'Taiwan Stock Exchange'), ('companies', '84')]
# [('stock', 'http://www.wikidata.org/entity/Q1805567'), ('stockName', 'Tehran Stock Exchange'), ('companies', '50')]
# [('stock', 'http://www.wikidata.org/entity/Q1507974'), ('stockName', 'Tel Aviv Stock Exchange'), ('companies', '55')]
# [('stock', 'http://www.wikidata.org/entity/Q18236250'), ('stockName', 'The Far East Exchange Limited'), ('companies', '1')]
# [('stock', 'http://www.wikidata.org/entity/Q11249728'), ('stockName', 'Tokyo Pro Market'), ('companies', '9')]
# [('stock', 'http://www.wikidata.org/entity/Q217475'), ('stockName', 'Tokyo Stock Exchange'), ('companies', '460')]
# [('stock', 'http://www.wikidata.org/entity/Q818723'), ('stockName', 'Toronto Stock Exchange'), ('companies', '394')]
# [('stock', 'http://www.wikidata.org/entity/Q1305960'), ('stockName', 'Tradegate Exchange'), ('companies', '1')]
# [('stock', 'http://www.wikidata.org/entity/Q4491717'), ('stockName', 'Trinidad and Tobago Stock Exchange'), ('companies', '2')]
# [('stock', 'http://www.wikidata.org/entity/Q4470480'), ('stockName', 'Ukrainian Exchange'), ('companies', '1')]
# [('stock', 'http://www.wikidata.org/entity/Q104438477'), ('stockName', 'Uniswap'), ('companies', '1')]
# [('stock', 'http://www.wikidata.org/entity/Q4202719'), ('stockName', 'Valencia Stock Exchange'), ('companies', '1')]
# [('stock', 'http://www.wikidata.org/entity/Q59551'), ('stockName', 'Warsaw Stock Exchange'), ('companies', '257')]
# [('stock', 'http://www.wikidata.org/entity/Q698535'), ('stockName', 'Wiener Börse'), ('companies', '16')]
# [('stock', 'http://www.wikidata.org/entity/Q819468'), ('stockName', 'Xetra'), ('companies', '6')]
# [('stock', 'http://www.wikidata.org/entity/Q20992132'), ('stockName', 'Yangon Stock Exchange'), ('companies', '6')]
# [('stock', 'http://www.wikidata.org/entity/Q140388'), ('stockName', 'Zagreb Stock Exchange'), ('companies', '12')]
# [('stock', 'http://www.wikidata.org/entity/Q5324516'), ('stockName', 'eToro'), ('companies', '2')]
# [('stock', 'http://www.wikidata.org/entity/Q66320'), ('stockName', 'over-the-counter trading'), ('companies', '2')]
# [('stock', 'http://www.wikidata.org/entity/Q1196314'), ('stockName', 'stock'), ('companies', '1')]
# [('stock', 'http://www.wikidata.org/entity/Q2387368'), ('stockName', 'zero two desnuda'), ('companies', '3')]
# 177

# %% [markdown]
# ## Task 8
# Identify the BGP for Academy Award

# %%
#look the property award recieved from the lion king. 
queryString = """
SELECT DISTINCT ?inst ?iname 
WHERE {
   # bind something
   wd:Q36479 ?p ?obj .
   # ?obj wdt:P166 ?inst.
   
   # get the label
   # ?inst sc:name ?iname.
}
ORDER BY ?iname
LIMIT 200
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('inst', 'http://www.wikidata.org/entity/Q52382875'), ('iname', 'AAAS Fellow')]
# [('inst', 'http://www.wikidata.org/entity/Q103916'), ('iname', 'Academy Award for Best Actor')]
# [('inst', 'http://www.wikidata.org/entity/Q106800'), ('iname', 'Academy Award for Best Animated Feature')]
# [('inst', 'http://www.wikidata.org/entity/Q488651'), ('iname', 'Academy Award for Best Original Score')]
# [('inst', 'http://www.wikidata.org/entity/Q112243'), ('iname', 'Academy Award for Best Original Song')]
# [('inst', 'http://www.wikidata.org/entity/Q106301'), ('iname', 'Academy Award for Best Supporting Actress')]
# [('inst', 'http://www.wikidata.org/entity/Q19020'), ('iname', 'Academy Awards')]
# [('inst', 'http://www.wikidata.org/entity/Q727328'), ('iname', 'Academy Honorary Award')]
# [('inst', 'http://www.wikidata.org/entity/Q8610'), ('iname', 'Academy Scientific and Technical Award')]
# [('inst', 'http://www.wikidata.org/entity/Q566905'), ('iname', 'Annie Award')]
# [('inst', 'http://www.wikidata.org/entity/Q103403908'), ('iname', 'Apple TV App of the Year')]
# [('inst', 'http://www.wikidata.org/entity/Q4969372'), ('iname', 'British Academy Television Award for Best Entertainment Performance')]
# [('inst', 'http://www.wikidata.org/entity/Q12201477'), ('iname', 'Commander of the Order of the British Empire')]
# [('inst', 'http://www.wikidata.org/entity/Q106517969'), ('iname', 'Crystal Award')]
# [('inst', 'http://www.wikidata.org/entity/Q56085709'), ('iname', 'Crystal Award')]
# [('inst', 'http://www.wikidata.org/entity/Q1179189'), ('iname', 'Daytime Emmy Award')]
# [('inst', 'http://www.wikidata.org/entity/Q1150306'), ('iname', 'Disney Legends')]
# [('inst', 'http://www.wikidata.org/entity/Q908858'), ('iname', 'Donostia Award')]
# [('inst', 'http://www.wikidata.org/entity/Q682154'), ('iname', 'Drama Desk Award')]
# [('inst', 'http://www.wikidata.org/entity/Q5305702'), ('iname', 'Drama Desk Award for Outstanding Actor in a Musical')]
# [('inst', 'http://www.wikidata.org/entity/Q123737'), ('iname', 'Emmy Award')]
# [('inst', 'http://www.wikidata.org/entity/Q77534812'), ('iname', 'European Film Academy Special Achievement Award')]
# [('inst', 'http://www.wikidata.org/entity/Q19858080'), ('iname', 'Favorite Pop/Rock Album')]
# [('inst', 'http://www.wikidata.org/entity/Q1534190'), ('iname', 'Goethe Plaque of the City of Frankfurt')]
# [('inst', 'http://www.wikidata.org/entity/Q3753203'), ('iname', 'Gold Medal of Merit in the Fine Arts (Spain)')]
# [('inst', 'http://www.wikidata.org/entity/Q1011547'), ('iname', 'Golden Globe Award')]
# [('inst', 'http://www.wikidata.org/entity/Q670282'), ('iname', 'Golden Globe Award for Best Motion Picture – Musical or Comedy')]
# [('inst', 'http://www.wikidata.org/entity/Q1472235'), ('iname', 'Golden Globe Award for Best Original Song')]
# [('inst', 'http://www.wikidata.org/entity/Q28867014'), ('iname', 'Golden Reel Award for Best Sound Editing: Music in a Feature Film')]
# [('inst', 'http://www.wikidata.org/entity/Q41254'), ('iname', 'Grammy Award')]
# [('inst', 'http://www.wikidata.org/entity/Q5593817'), ('iname', 'Grammy Award for Best Arrangement, Instrumental and Vocals')]
# [('inst', 'http://www.wikidata.org/entity/Q5593836'), ('iname', 'Grammy Award for Best Musical Album for Children')]
# [('inst', 'http://www.wikidata.org/entity/Q428808'), ('iname', 'Grammy Award for Best Song Written for Visual Media')]
# [('inst', 'http://www.wikidata.org/entity/Q3113382'), ('iname', 'Grammy Award for Best Spoken Word Album for Children')]
# [('inst', 'http://www.wikidata.org/entity/Q1027904'), ('iname', 'Grammy Award for Song of the Year')]
# [('inst', 'http://www.wikidata.org/entity/Q1542347'), ('iname', 'Grammy Legend Award')]
# [('inst', 'http://www.wikidata.org/entity/Q28950956'), ('iname', 'Horatio Alger Award')]
# [('inst', 'http://www.wikidata.org/entity/Q33232596'), ('iname', 'Humanitarian of the Year')]
# [('inst', 'http://www.wikidata.org/entity/Q61669648'), ('iname', 'Johnny Mercer Award')]
# [('inst', 'http://www.wikidata.org/entity/Q1738793'), ('iname', 'Kennedy Center Honors')]
# [('inst', 'http://www.wikidata.org/entity/Q833163'), ('iname', 'Knight Bachelor')]
# [('inst', 'http://www.wikidata.org/entity/Q10855271'), ('iname', 'Knight of the Legion of Honour')]
# [('inst', 'http://www.wikidata.org/entity/Q28470'), ('iname', 'Laurence Olivier Award')]
# [('inst', 'http://www.wikidata.org/entity/Q6500777'), ('iname', 'Laurence Olivier Award for Best Comedy Performance')]
# [('inst', 'http://www.wikidata.org/entity/Q6500795'), ('iname', 'Laurence Olivier Award for Best New Musical')]
# [('inst', 'http://www.wikidata.org/entity/Q163700'), ('iname', 'Legion of Honour')]
# [('inst', 'http://www.wikidata.org/entity/Q1899850'), ('iname', 'Mark Twain Prize for American Humor')]
# [('inst', 'http://www.wikidata.org/entity/Q326482'), ('iname', 'MusiCares Person of the Year')]
# [('inst', 'http://www.wikidata.org/entity/Q1789030'), ('iname', 'National Medal of Arts')]
# [('inst', 'http://www.wikidata.org/entity/Q10905334'), ('iname', "Officer's Cross of the Order of Merit of the Federal Republic of Germany")]
# [('inst', 'http://www.wikidata.org/entity/Q13452524'), ('iname', 'Officier des Arts et des Lettres\u200e')]
# [('inst', 'http://www.wikidata.org/entity/Q14420'), ('iname', 'Order of the British Empire')]
# [('inst', 'http://www.wikidata.org/entity/Q1137694'), ('iname', 'Order of the Companions of Honour')]
# [('inst', 'http://www.wikidata.org/entity/Q716909'), ('iname', 'Ordre des Arts et des Lettres')]
# [('inst', 'http://www.wikidata.org/entity/Q7153268'), ('iname', 'Paul Robeson Award')]
# [('inst', 'http://www.wikidata.org/entity/Q838121'), ('iname', 'Peabody Awards')]
# [('inst', 'http://www.wikidata.org/entity/Q989442'), ('iname', 'Primetime Emmy Award for Outstanding Lead Actor in a Comedy Series')]
# [('inst', 'http://www.wikidata.org/entity/Q989439'), ('iname', 'Primetime Emmy Award for Outstanding Lead Actor in a Drama Series')]
# [('inst', 'http://www.wikidata.org/entity/Q1285970'), ('iname', 'Primetime Emmy Award for Outstanding Supporting Actor in a Comedy Series')]
# [('inst', 'http://www.wikidata.org/entity/Q945887'), ('iname', 'Primetime Emmy Award for Outstanding Supporting Actor in a Miniseries or a Movie')]
# [('inst', 'http://www.wikidata.org/entity/Q1285504'), ('iname', 'Primetime Emmy Award for Outstanding Supporting Actress in a Drama Series')]
# [('inst', 'http://www.wikidata.org/entity/Q179191'), ('iname', 'Rock and Roll Hall of Fame')]
# [('inst', 'http://www.wikidata.org/entity/Q17126095'), ('iname', 'Russ Manning Award')]
# [('inst', 'http://www.wikidata.org/entity/Q2620855'), ('iname', 'Satellite Award for Best Animated or Mixed Media Feature')]
# [('inst', 'http://www.wikidata.org/entity/Q3473891'), ('iname', 'Satellite Award for Best Television Series – Musical or Comedy')]
# [('inst', 'http://www.wikidata.org/entity/Q1631998'), ('iname', 'Screen Actors Guild Life Achievement Award')]
# [('inst', 'http://www.wikidata.org/entity/Q3483987'), ('iname', 'Silver Clef Award')]
# [('inst', 'http://www.wikidata.org/entity/Q30144811'), ('iname', 'Stephen Hawking Medal For Science Communication')]
# [('inst', 'http://www.wikidata.org/entity/Q1131356'), ('iname', 'Theatre World Award')]
# [('inst', 'http://www.wikidata.org/entity/Q1723064'), ('iname', 'Tony Award for Best Actor in a Musical')]
# [('inst', 'http://www.wikidata.org/entity/Q1445521'), ('iname', 'Tony Award for Best Actor in a Play')]
# [('inst', 'http://www.wikidata.org/entity/Q1474410'), ('iname', 'Tony Award for Best Featured Actor in a Play')]
# [('inst', 'http://www.wikidata.org/entity/Q191874'), ('iname', 'Tony Awards')]
# [('inst', 'http://www.wikidata.org/entity/Q7927224'), ('iname', 'Victorian Honour Roll of Women')]
# [('inst', 'http://www.wikidata.org/entity/Q8025998'), ('iname', 'Winsor McCay Award')]
# [('inst', 'http://www.wikidata.org/entity/Q86241109'), ('iname', 'honorary doctor of Brandeis University')]
# [('inst', 'http://www.wikidata.org/entity/Q39384825'), ('iname', 'honorary doctor of Harvard University')]
# [('inst', 'http://www.wikidata.org/entity/Q17985761'), ('iname', 'star on Hollywood Walk of Fame')]
# 78

# %% [markdown]
# Final query for this task

# %%
#I see Academy awards on the list from the awards recieved by the lion king Q19020
queryString = """
SELECT DISTINCT ?inst ?iname 
WHERE {
   # bind something
   wd:Q36479 ?p ?obj .
   # ?obj wdt:P166 ?inst.
   
   VALUES ?inst {wd:Q19020}
   # get the label
   # ?inst sc:name ?iname.
}
ORDER BY ?iname
LIMIT 200
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('inst', 'http://www.wikidata.org/entity/Q19020'), ('iname', 'Academy Awards')]
# 1

# %% [markdown]
# ## Task 9
# Find the companies (among television and film production companies) that won at least 5 Academy Awards for Best Actress for the movies they produced (the result set must be a list of triples company IRI, label and #awards).

# %%
#First I'll look for the films that won the academy awards for best Actress but for do that I have to get the identifier for Academy awards for 
#best actress. 
queryString = """
SELECT DISTINCT ?inst ?iname 
WHERE {
   # bind something
   # ?inst wdt:P31 wd:Q19020 .
   
   
   # get the label
   # ?inst sc:name ?iname.
}
ORDER BY ?iname
LIMIT 200
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('inst', 'http://www.wikidata.org/entity/Q103916'), ('iname', 'Academy Award for Best Actor')]
# [('inst', 'http://www.wikidata.org/entity/Q103618'), ('iname', 'Academy Award for Best Actress')]
# [('inst', 'http://www.wikidata.org/entity/Q106800'), ('iname', 'Academy Award for Best Animated Feature')]
# [('inst', 'http://www.wikidata.org/entity/Q917808'), ('iname', 'Academy Award for Best Animated Short Film')]
# [('inst', 'http://www.wikidata.org/entity/Q22253133'), ('iname', 'Academy Award for Best Art Direction, Black and White')]
# [('inst', 'http://www.wikidata.org/entity/Q22253131'), ('iname', 'Academy Award for Best Art Direction, Color')]
# [('inst', 'http://www.wikidata.org/entity/Q501004'), ('iname', 'Academy Award for Best Assistant Director')]
# [('inst', 'http://www.wikidata.org/entity/Q131520'), ('iname', 'Academy Award for Best Cinematography')]
# [('inst', 'http://www.wikidata.org/entity/Q21995139'), ('iname', 'Academy Award for Best Cinematography, Black-and-White')]
# [('inst', 'http://www.wikidata.org/entity/Q21995136'), ('iname', 'Academy Award for Best Cinematography, Color')]
# [('inst', 'http://www.wikidata.org/entity/Q277536'), ('iname', 'Academy Award for Best Costume Design')]
# [('inst', 'http://www.wikidata.org/entity/Q22120095'), ('iname', 'Academy Award for Best Costume Design, Black-and-White')]
# [('inst', 'http://www.wikidata.org/entity/Q22120066'), ('iname', 'Academy Award for Best Costume Design, Color')]
# [('inst', 'http://www.wikidata.org/entity/Q498690'), ('iname', 'Academy Award for Best Dance Direction')]
# [('inst', 'http://www.wikidata.org/entity/Q103360'), ('iname', 'Academy Award for Best Director')]
# [('inst', 'http://www.wikidata.org/entity/Q3451157'), ('iname', 'Academy Award for Best Director (Comedy picture)')]
# [('inst', 'http://www.wikidata.org/entity/Q21995338'), ('iname', 'Academy Award for Best Director, Dramatic Picture')]
# [('inst', 'http://www.wikidata.org/entity/Q1425151'), ('iname', 'Academy Award for Best Documentary (Short Subject)')]
# [('inst', 'http://www.wikidata.org/entity/Q111332'), ('iname', 'Academy Award for Best Documentary Feature')]
# [('inst', 'http://www.wikidata.org/entity/Q3886463'), ('iname', 'Academy Award for Best Engineering Effects')]
# [('inst', 'http://www.wikidata.org/entity/Q281939'), ('iname', 'Academy Award for Best Film Editing')]
# [('inst', 'http://www.wikidata.org/entity/Q105304'), ('iname', 'Academy Award for Best Foreign Language Film')]
# [('inst', 'http://www.wikidata.org/entity/Q1324407'), ('iname', 'Academy Award for Best Live Action Short Film')]
# [('inst', 'http://www.wikidata.org/entity/Q3886465'), ('iname', 'Academy Award for Best Live Action Short Film, Color')]
# [('inst', 'http://www.wikidata.org/entity/Q3886464'), ('iname', 'Academy Award for Best Live Action Short Film, Comedy')]
# [('inst', 'http://www.wikidata.org/entity/Q22335251'), ('iname', 'Academy Award for Best Live Action Short Film, One-Reel')]
# [('inst', 'http://www.wikidata.org/entity/Q487136'), ('iname', 'Academy Award for Best Makeup and Hairstyling')]
# [('inst', 'http://www.wikidata.org/entity/Q22235329'), ('iname', 'Academy Award for Best Original Dramatic Score')]
# [('inst', 'http://www.wikidata.org/entity/Q22752868'), ('iname', 'Academy Award for Best Original Dramatic or Comedy Score')]
# [('inst', 'http://www.wikidata.org/entity/Q4671338'), ('iname', 'Academy Award for Best Original Musical Score')]
# [('inst', 'http://www.wikidata.org/entity/Q22235305'), ('iname', 'Academy Award for Best Original Musical or Comedy Score')]
# [('inst', 'http://www.wikidata.org/entity/Q488651'), ('iname', 'Academy Award for Best Original Score')]
# [('inst', 'http://www.wikidata.org/entity/Q22752734'), ('iname', 'Academy Award for Best Original Score, no Musical')]
# [('inst', 'http://www.wikidata.org/entity/Q112243'), ('iname', 'Academy Award for Best Original Song')]
# [('inst', 'http://www.wikidata.org/entity/Q22344608'), ('iname', 'Academy Award for Best Original Song Score')]
# [('inst', 'http://www.wikidata.org/entity/Q102427'), ('iname', 'Academy Award for Best Picture')]
# [('inst', 'http://www.wikidata.org/entity/Q277751'), ('iname', 'Academy Award for Best Production Design')]
# [('inst', 'http://www.wikidata.org/entity/Q22752811'), ('iname', 'Academy Award for Best Score, Adaptation or Treatment')]
# [('inst', 'http://www.wikidata.org/entity/Q2297175'), ('iname', 'Academy Award for Best Short Subject, Novelty')]
# [('inst', 'http://www.wikidata.org/entity/Q1401974'), ('iname', 'Academy Award for Best Short Subject, Two-reel')]
# [('inst', 'http://www.wikidata.org/entity/Q830079'), ('iname', 'Academy Award for Best Sound')]
# [('inst', 'http://www.wikidata.org/entity/Q488645'), ('iname', 'Academy Award for Best Sound Editing')]
# [('inst', 'http://www.wikidata.org/entity/Q22917729'), ('iname', 'Academy Award for Best Special Effects')]
# [('inst', 'http://www.wikidata.org/entity/Q504298'), ('iname', 'Academy Award for Best Story')]
# [('inst', 'http://www.wikidata.org/entity/Q106291'), ('iname', 'Academy Award for Best Supporting Actor')]
# [('inst', 'http://www.wikidata.org/entity/Q106301'), ('iname', 'Academy Award for Best Supporting Actress')]
# [('inst', 'http://www.wikidata.org/entity/Q3886486'), ('iname', 'Academy Award for Best Title Writing')]
# [('inst', 'http://www.wikidata.org/entity/Q31193514'), ('iname', 'Academy Award for Best Unique and Artistic Picture')]
# [('inst', 'http://www.wikidata.org/entity/Q393686'), ('iname', 'Academy Award for Best Visual Effects')]
# [('inst', 'http://www.wikidata.org/entity/Q22117120'), ('iname', 'Academy Award for Best Writing')]
# [('inst', 'http://www.wikidata.org/entity/Q107258'), ('iname', 'Academy Award for Best Writing, Adapted Screenplay')]
# [('inst', 'http://www.wikidata.org/entity/Q41417'), ('iname', 'Academy Award for Best Writing, Original Screenplay')]
# [('inst', 'http://www.wikidata.org/entity/Q8636'), ('iname', 'Academy Award for Technical Achievement')]
# [('inst', 'http://www.wikidata.org/entity/Q3298549'), ('iname', 'Academy Award for Unique and Artistic Production')]
# [('inst', 'http://www.wikidata.org/entity/Q8624'), ('iname', 'Academy Award of Merit')]
# [('inst', 'http://www.wikidata.org/entity/Q98924004'), ('iname', 'Academy Award to the Producer of the Best Film')]
# [('inst', 'http://www.wikidata.org/entity/Q727328'), ('iname', 'Academy Honorary Award')]
# [('inst', 'http://www.wikidata.org/entity/Q489705'), ('iname', 'Academy Juvenile Award')]
# [('inst', 'http://www.wikidata.org/entity/Q8610'), ('iname', 'Academy Scientific and Technical Award')]
# [('inst', 'http://www.wikidata.org/entity/Q488151'), ('iname', 'Gordon E. Sawyer Award')]
# [('inst', 'http://www.wikidata.org/entity/Q844273'), ('iname', 'Irving G. Thalberg Memorial Award')]
# [('inst', 'http://www.wikidata.org/entity/Q8250869'), ('iname', 'Scientific and Engineering Award')]
# [('inst', 'http://www.wikidata.org/entity/Q2032630'), ('iname', 'Special Achievement Academy Award')]
# 63

# %%
#Now I get all the films that won the Academy Award for best actress Q103618
queryString = """
SELECT DISTINCT ?film ?filmName 
WHERE {

   # bind something
   # ?film wdt:P31 wd:Q11424 . #I get all the films. 
   # ?film wdt:P166 wd:Q103618. #Now I filter to only get the ones that won the award. 
   
   
   
   # get the label
   # ?film sc:name ?filmName.
}
ORDER BY ?filmName
LIMIT 200
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('film', 'http://www.wikidata.org/entity/Q212129'), ('filmName', 'A Streetcar Named Desire')]
# [('film', 'http://www.wikidata.org/entity/Q1622883'), ('filmName', 'A Touch of Class')]
# [('film', 'http://www.wikidata.org/entity/Q916431'), ('filmName', "Alice Doesn't Live Here Anymore")]
# [('film', 'http://www.wikidata.org/entity/Q486591'), ('filmName', 'Anastasia')]
# [('film', 'http://www.wikidata.org/entity/Q233464'), ('filmName', 'Annie Hall')]
# [('film', 'http://www.wikidata.org/entity/Q221594'), ('filmName', 'As Good as It Gets')]
# [('film', 'http://www.wikidata.org/entity/Q180214'), ('filmName', 'Black Swan')]
# [('film', 'http://www.wikidata.org/entity/Q2907178'), ('filmName', 'Blue Jasmine')]
# [('film', 'http://www.wikidata.org/entity/Q1849813'), ('filmName', 'Blue Sky')]
# [('film', 'http://www.wikidata.org/entity/Q375594'), ('filmName', 'Born Yesterday')]
# [('film', 'http://www.wikidata.org/entity/Q465646'), ('filmName', "Boys Don't Cry")]
# [('film', 'http://www.wikidata.org/entity/Q652069'), ('filmName', 'Butterfield 8')]
# [('film', 'http://www.wikidata.org/entity/Q918363'), ('filmName', 'Cabaret')]
# [('film', 'http://www.wikidata.org/entity/Q1323446'), ('filmName', 'Children of a Lesser God')]
# [('film', 'http://www.wikidata.org/entity/Q1285467'), ('filmName', "Coal Miner's Daughter")]
# [('film', 'http://www.wikidata.org/entity/Q1737875'), ('filmName', 'Come Back, Little Sheba')]
# [('film', 'http://www.wikidata.org/entity/Q1114683'), ('filmName', 'Coming Home')]
# [('film', 'http://www.wikidata.org/entity/Q570506'), ('filmName', 'Coquette')]
# [('film', 'http://www.wikidata.org/entity/Q849336'), ('filmName', 'Dangerous')]
# [('film', 'http://www.wikidata.org/entity/Q1166360'), ('filmName', 'Darling')]
# [('film', 'http://www.wikidata.org/entity/Q587891'), ('filmName', 'Dead Man Walking')]
# [('film', 'http://www.wikidata.org/entity/Q211373'), ('filmName', 'Driving Miss Daisy')]
# [('film', 'http://www.wikidata.org/entity/Q220955'), ('filmName', 'Erin Brockovich')]
# [('film', 'http://www.wikidata.org/entity/Q222720'), ('filmName', 'Fargo')]
# [('film', 'http://www.wikidata.org/entity/Q1364076'), ('filmName', 'Funny Girl')]
# [('film', 'http://www.wikidata.org/entity/Q841781'), ('filmName', 'Gaslight')]
# [('film', 'http://www.wikidata.org/entity/Q2875'), ('filmName', 'Gone with the Wind')]
# [('film', 'http://www.wikidata.org/entity/Q736969'), ('filmName', "Guess Who's Coming to Dinner")]
# [('film', 'http://www.wikidata.org/entity/Q913389'), ('filmName', 'Howards End')]
# [('film', 'http://www.wikidata.org/entity/Q1198073'), ('filmName', 'Hud')]
# [('film', 'http://www.wikidata.org/entity/Q1809616'), ('filmName', 'I Want to Live!')]
# [('film', 'http://www.wikidata.org/entity/Q208632'), ('filmName', 'It Happened One Night')]
# [('film', 'http://www.wikidata.org/entity/Q618741'), ('filmName', 'Jezebel')]
# [('film', 'http://www.wikidata.org/entity/Q1439574'), ('filmName', 'Johnny Belinda')]
# [('film', 'http://www.wikidata.org/entity/Q55615419'), ('filmName', 'Judy')]
# [('film', 'http://www.wikidata.org/entity/Q1471328'), ('filmName', 'Kitty Foyle')]
# [('film', 'http://www.wikidata.org/entity/Q1348177'), ('filmName', 'Klute')]
# [('film', 'http://www.wikidata.org/entity/Q20856802'), ('filmName', 'La La Land')]
# [('film', 'http://www.wikidata.org/entity/Q236217'), ('filmName', 'La Vie en Rose')]
# [('film', 'http://www.wikidata.org/entity/Q979726'), ('filmName', 'Mildred Pierce')]
# [('film', 'http://www.wikidata.org/entity/Q184255'), ('filmName', 'Million Dollar Baby')]
# [('film', 'http://www.wikidata.org/entity/Q1089809'), ('filmName', 'Min and Bill')]
# [('film', 'http://www.wikidata.org/entity/Q725552'), ('filmName', 'Misery')]
# [('film', 'http://www.wikidata.org/entity/Q459057'), ('filmName', 'Monster')]
# [('film', 'http://www.wikidata.org/entity/Q1124875'), ('filmName', "Monster's Ball")]
# [('film', 'http://www.wikidata.org/entity/Q1336107'), ('filmName', 'Moonstruck')]
# [('film', 'http://www.wikidata.org/entity/Q572789'), ('filmName', 'Morning Glory')]
# [('film', 'http://www.wikidata.org/entity/Q478371'), ('filmName', 'Mrs. Miniver')]
# [('film', 'http://www.wikidata.org/entity/Q572165'), ('filmName', 'Network')]
# [('film', 'http://www.wikidata.org/entity/Q1419066'), ('filmName', 'Norma Rae')]
# [('film', 'http://www.wikidata.org/entity/Q451603'), ('filmName', 'On Golden Pond')]
# [('film', 'http://www.wikidata.org/entity/Q171669'), ('filmName', "One Flew Over the Cuckoo's Nest")]
# [('film', 'http://www.wikidata.org/entity/Q59073'), ('filmName', 'Places in the Heart')]
# [('film', 'http://www.wikidata.org/entity/Q201293'), ('filmName', 'Roman Holiday')]
# [('film', 'http://www.wikidata.org/entity/Q18703032'), ('filmName', 'Room')]
# [('film', 'http://www.wikidata.org/entity/Q617997'), ('filmName', 'Room at the Top')]
# [('film', 'http://www.wikidata.org/entity/Q182944'), ('filmName', 'Shakespeare in Love')]
# [('film', 'http://www.wikidata.org/entity/Q116845'), ('filmName', 'Silver Linings Playbook')]
# [('film', 'http://www.wikidata.org/entity/Q165627'), ('filmName', "Sophie's Choice")]
# [('film', 'http://www.wikidata.org/entity/Q16354843'), ('filmName', 'Still Alice')]
# [('film', 'http://www.wikidata.org/entity/Q1077902'), ('filmName', 'Street Angel')]
# [('film', 'http://www.wikidata.org/entity/Q1509470'), ('filmName', 'Suspicion')]
# [('film', 'http://www.wikidata.org/entity/Q185071'), ('filmName', 'Terms of Endearment')]
# [('film', 'http://www.wikidata.org/entity/Q531310'), ('filmName', 'The Accused')]
# [('film', 'http://www.wikidata.org/entity/Q206497'), ('filmName', 'The Blind Side')]
# [('film', 'http://www.wikidata.org/entity/Q1305029'), ('filmName', 'The Country Girl')]
# [('film', 'http://www.wikidata.org/entity/Q917469'), ('filmName', 'The Divorcee')]
# [('film', 'http://www.wikidata.org/entity/Q262783'), ('filmName', "The Farmer's Daughter")]
# [('film', 'http://www.wikidata.org/entity/Q22001133'), ('filmName', 'The Favourite')]
# [('film', 'http://www.wikidata.org/entity/Q612540'), ('filmName', 'The Good Earth')]
# [('film', 'http://www.wikidata.org/entity/Q470218'), ('filmName', 'The Great Ziegfeld')]
# [('film', 'http://www.wikidata.org/entity/Q1141493'), ('filmName', 'The Heiress')]
# [('film', 'http://www.wikidata.org/entity/Q157044'), ('filmName', 'The Hours')]
# [('film', 'http://www.wikidata.org/entity/Q269810'), ('filmName', 'The Iron Lady')]
# [('film', 'http://www.wikidata.org/entity/Q1195311'), ('filmName', 'The Lion in Winter')]
# [('film', 'http://www.wikidata.org/entity/Q287536'), ('filmName', 'The Miracle Worker')]
# [('film', 'http://www.wikidata.org/entity/Q117315'), ('filmName', 'The Piano')]
# [('film', 'http://www.wikidata.org/entity/Q667764'), ('filmName', 'The Prime of Miss Jean Brodie')]
# [('film', 'http://www.wikidata.org/entity/Q223367'), ('filmName', 'The Queen')]
# [('film', 'http://www.wikidata.org/entity/Q159063'), ('filmName', 'The Reader')]
# [('film', 'http://www.wikidata.org/entity/Q634694'), ('filmName', 'The Rose Tattoo')]
# [('film', 'http://www.wikidata.org/entity/Q133654'), ('filmName', 'The Silence of the Lambs')]
# [('film', 'http://www.wikidata.org/entity/Q940054'), ('filmName', 'The Sin of Madelon Claudet')]
# [('film', 'http://www.wikidata.org/entity/Q669749'), ('filmName', 'The Song of Bernadette')]
# [('film', 'http://www.wikidata.org/entity/Q1379585'), ('filmName', 'The Three Faces of Eve')]
# [('film', 'http://www.wikidata.org/entity/Q2521361'), ('filmName', 'The Trip to Bountiful')]
# [('film', 'http://www.wikidata.org/entity/Q24053277'), ('filmName', 'Three Billboards Outside Ebbing, Missouri')]
# [('film', 'http://www.wikidata.org/entity/Q1627707'), ('filmName', 'To Each His Own')]
# [('film', 'http://www.wikidata.org/entity/Q128761'), ('filmName', 'Two Women')]
# [('film', 'http://www.wikidata.org/entity/Q154077'), ('filmName', 'Walk the Line')]
# [('film', 'http://www.wikidata.org/entity/Q325643'), ('filmName', "Who's Afraid of Virginia Woolf?")]
# [('film', 'http://www.wikidata.org/entity/Q630132'), ('filmName', 'Women in Love')]
# 92

# %%
#Now I have all the movies that won the award for the best actress, I have to get the company. 
queryString = """
SELECT DISTINCT ?film ?filmName ?companyName
WHERE {

   # bind something
   # ?film wdt:P31 wd:Q11424 . #I get all the films. 
   # ?film wdt:P166 wd:Q103618. #Now I filter to only get the ones that won the award. 
   # ?film wdt:P272 ?company. 
   
   
   # get the label
   # ?film sc:name ?filmName.
   # ?company sc:name ?companyName. 
}
ORDER BY ?filmName
LIMIT 200
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('film', 'http://www.wikidata.org/entity/Q212129'), ('filmName', 'A Streetcar Named Desire'), ('companyName', 'Warner Bros.')]
# [('film', 'http://www.wikidata.org/entity/Q916431'), ('filmName', "Alice Doesn't Live Here Anymore"), ('companyName', 'Warner Bros.')]
# [('film', 'http://www.wikidata.org/entity/Q486591'), ('filmName', 'Anastasia'), ('companyName', '20th Century Studios')]
# [('film', 'http://www.wikidata.org/entity/Q221594'), ('filmName', 'As Good as It Gets'), ('companyName', 'TriStar Pictures')]
# [('film', 'http://www.wikidata.org/entity/Q221594'), ('filmName', 'As Good as It Gets'), ('companyName', 'Gracie Films')]
# [('film', 'http://www.wikidata.org/entity/Q180214'), ('filmName', 'Black Swan'), ('companyName', 'Phoenix Pictures')]
# [('film', 'http://www.wikidata.org/entity/Q180214'), ('filmName', 'Black Swan'), ('companyName', 'RatPac-Dune Entertainment')]
# [('film', 'http://www.wikidata.org/entity/Q1849813'), ('filmName', 'Blue Sky'), ('companyName', 'Orion Pictures')]
# [('film', 'http://www.wikidata.org/entity/Q375594'), ('filmName', 'Born Yesterday'), ('companyName', 'Columbia Pictures')]
# [('film', 'http://www.wikidata.org/entity/Q465646'), ('filmName', "Boys Don't Cry"), ('companyName', 'Killer Films')]
# [('film', 'http://www.wikidata.org/entity/Q465646'), ('filmName', "Boys Don't Cry"), ('companyName', 'Searchlight Pictures')]
# [('film', 'http://www.wikidata.org/entity/Q652069'), ('filmName', 'Butterfield 8'), ('companyName', 'Metro-Goldwyn-Mayer')]
# [('film', 'http://www.wikidata.org/entity/Q918363'), ('filmName', 'Cabaret'), ('companyName', 'Monogram Pictures')]
# [('film', 'http://www.wikidata.org/entity/Q1323446'), ('filmName', 'Children of a Lesser God'), ('companyName', 'Paramount Pictures')]
# [('film', 'http://www.wikidata.org/entity/Q1285467'), ('filmName', "Coal Miner's Daughter"), ('companyName', 'Universal Pictures')]
# [('film', 'http://www.wikidata.org/entity/Q1737875'), ('filmName', 'Come Back, Little Sheba'), ('companyName', 'Paramount Pictures')]
# [('film', 'http://www.wikidata.org/entity/Q849336'), ('filmName', 'Dangerous'), ('companyName', 'Warner Bros.')]
# [('film', 'http://www.wikidata.org/entity/Q587891'), ('filmName', 'Dead Man Walking'), ('companyName', 'Working Title Films')]
# [('film', 'http://www.wikidata.org/entity/Q587891'), ('filmName', 'Dead Man Walking'), ('companyName', 'PolyGram Filmed Entertainment')]
# [('film', 'http://www.wikidata.org/entity/Q211373'), ('filmName', 'Driving Miss Daisy'), ('companyName', 'Warner Bros.')]
# [('film', 'http://www.wikidata.org/entity/Q220955'), ('filmName', 'Erin Brockovich'), ('companyName', 'Jersey Group')]
# [('film', 'http://www.wikidata.org/entity/Q222720'), ('filmName', 'Fargo'), ('companyName', 'Working Title Films')]
# [('film', 'http://www.wikidata.org/entity/Q222720'), ('filmName', 'Fargo'), ('companyName', 'PolyGram Filmed Entertainment')]
# [('film', 'http://www.wikidata.org/entity/Q1364076'), ('filmName', 'Funny Girl'), ('companyName', 'Columbia Pictures')]
# [('film', 'http://www.wikidata.org/entity/Q1364076'), ('filmName', 'Funny Girl'), ('companyName', 'Rastar')]
# [('film', 'http://www.wikidata.org/entity/Q841781'), ('filmName', 'Gaslight'), ('companyName', 'Metro-Goldwyn-Mayer')]
# [('film', 'http://www.wikidata.org/entity/Q2875'), ('filmName', 'Gone with the Wind'), ('companyName', 'Metro-Goldwyn-Mayer')]
# [('film', 'http://www.wikidata.org/entity/Q2875'), ('filmName', 'Gone with the Wind'), ('companyName', 'Selznick International Pictures')]
# [('film', 'http://www.wikidata.org/entity/Q736969'), ('filmName', "Guess Who's Coming to Dinner"), ('companyName', 'Columbia Pictures')]
# [('film', 'http://www.wikidata.org/entity/Q913389'), ('filmName', 'Howards End'), ('companyName', 'Merchant Ivory Productions')]
# [('film', 'http://www.wikidata.org/entity/Q1198073'), ('filmName', 'Hud'), ('companyName', 'Paramount Pictures')]
# [('film', 'http://www.wikidata.org/entity/Q208632'), ('filmName', 'It Happened One Night'), ('companyName', 'Columbia Pictures')]
# [('film', 'http://www.wikidata.org/entity/Q618741'), ('filmName', 'Jezebel'), ('companyName', 'Warner Bros.')]
# [('film', 'http://www.wikidata.org/entity/Q1439574'), ('filmName', 'Johnny Belinda'), ('companyName', 'Warner Bros.')]
# [('film', 'http://www.wikidata.org/entity/Q55615419'), ('filmName', 'Judy'), ('companyName', 'BBC Film')]
# [('film', 'http://www.wikidata.org/entity/Q1471328'), ('filmName', 'Kitty Foyle'), ('companyName', 'RKO Pictures')]
# [('film', 'http://www.wikidata.org/entity/Q1348177'), ('filmName', 'Klute'), ('companyName', 'Warner Bros.')]
# [('film', 'http://www.wikidata.org/entity/Q20856802'), ('filmName', 'La La Land'), ('companyName', 'Summit Entertainment')]
# [('film', 'http://www.wikidata.org/entity/Q20856802'), ('filmName', 'La La Land'), ('companyName', 'Lionsgate')]
# [('film', 'http://www.wikidata.org/entity/Q236217'), ('filmName', 'La Vie en Rose'), ('companyName', 'TF1 Films Production')]
# [('film', 'http://www.wikidata.org/entity/Q236217'), ('filmName', 'La Vie en Rose'), ('companyName', 'Légende Entreprises')]
# [('film', 'http://www.wikidata.org/entity/Q236217'), ('filmName', 'La Vie en Rose'), ('companyName', 'TF1 International')]
# [('film', 'http://www.wikidata.org/entity/Q236217'), ('filmName', 'La Vie en Rose'), ('companyName', 'Okko Production')]
# [('film', 'http://www.wikidata.org/entity/Q236217'), ('filmName', 'La Vie en Rose'), ('companyName', 'Songbird Pictures')]
# [('film', 'http://www.wikidata.org/entity/Q979726'), ('filmName', 'Mildred Pierce'), ('companyName', 'Warner Bros.')]
# [('film', 'http://www.wikidata.org/entity/Q184255'), ('filmName', 'Million Dollar Baby'), ('companyName', 'Lakeshore Entertainment')]
# [('film', 'http://www.wikidata.org/entity/Q184255'), ('filmName', 'Million Dollar Baby'), ('companyName', 'Malpaso Productions')]
# [('film', 'http://www.wikidata.org/entity/Q1089809'), ('filmName', 'Min and Bill'), ('companyName', 'Metro-Goldwyn-Mayer')]
# [('film', 'http://www.wikidata.org/entity/Q725552'), ('filmName', 'Misery'), ('companyName', 'Embassy Pictures')]
# [('film', 'http://www.wikidata.org/entity/Q725552'), ('filmName', 'Misery'), ('companyName', 'Castle Rock Entertainment')]
# [('film', 'http://www.wikidata.org/entity/Q459057'), ('filmName', 'Monster'), ('companyName', 'DEJ Productions')]
# [('film', 'http://www.wikidata.org/entity/Q1124875'), ('filmName', "Monster's Ball"), ('companyName', 'Lionsgate')]
# [('film', 'http://www.wikidata.org/entity/Q1336107'), ('filmName', 'Moonstruck'), ('companyName', 'Metro-Goldwyn-Mayer')]
# [('film', 'http://www.wikidata.org/entity/Q572789'), ('filmName', 'Morning Glory'), ('companyName', 'RKO Pictures')]
# [('film', 'http://www.wikidata.org/entity/Q478371'), ('filmName', 'Mrs. Miniver'), ('companyName', 'Metro-Goldwyn-Mayer')]
# [('film', 'http://www.wikidata.org/entity/Q572165'), ('filmName', 'Network'), ('companyName', 'Metro-Goldwyn-Mayer')]
# [('film', 'http://www.wikidata.org/entity/Q572165'), ('filmName', 'Network'), ('companyName', 'United Artists Corporation')]
# [('film', 'http://www.wikidata.org/entity/Q451603'), ('filmName', 'On Golden Pond'), ('companyName', 'ITC Entertainment')]
# [('film', 'http://www.wikidata.org/entity/Q171669'), ('filmName', "One Flew Over the Cuckoo's Nest"), ('companyName', 'Fantasy Films Productions')]
# [('film', 'http://www.wikidata.org/entity/Q201293'), ('filmName', 'Roman Holiday'), ('companyName', 'Paramount Pictures')]
# [('film', 'http://www.wikidata.org/entity/Q182944'), ('filmName', 'Shakespeare in Love'), ('companyName', 'Universal Pictures')]
# [('film', 'http://www.wikidata.org/entity/Q116845'), ('filmName', 'Silver Linings Playbook'), ('companyName', 'The Weinstein Company')]
# [('film', 'http://www.wikidata.org/entity/Q116845'), ('filmName', 'Silver Linings Playbook'), ('companyName', 'Mirage Enterprises')]
# [('film', 'http://www.wikidata.org/entity/Q165627'), ('filmName', "Sophie's Choice"), ('companyName', 'ITC Entertainment')]
# [('film', 'http://www.wikidata.org/entity/Q16354843'), ('filmName', 'Still Alice'), ('companyName', 'Killer Films')]
# [('film', 'http://www.wikidata.org/entity/Q1077902'), ('filmName', 'Street Angel'), ('companyName', 'Fox Film')]
# [('film', 'http://www.wikidata.org/entity/Q1509470'), ('filmName', 'Suspicion'), ('companyName', 'RKO Pictures')]
# [('film', 'http://www.wikidata.org/entity/Q185071'), ('filmName', 'Terms of Endearment'), ('companyName', 'Paramount Pictures')]
# [('film', 'http://www.wikidata.org/entity/Q531310'), ('filmName', 'The Accused'), ('companyName', 'Paramount Pictures')]
# [('film', 'http://www.wikidata.org/entity/Q206497'), ('filmName', 'The Blind Side'), ('companyName', 'Fortis Films')]
# [('film', 'http://www.wikidata.org/entity/Q206497'), ('filmName', 'The Blind Side'), ('companyName', 'Alcon Entertainment')]
# [('film', 'http://www.wikidata.org/entity/Q1305029'), ('filmName', 'The Country Girl'), ('companyName', 'Paramount Pictures')]
# [('film', 'http://www.wikidata.org/entity/Q917469'), ('filmName', 'The Divorcee'), ('companyName', 'Metro-Goldwyn-Mayer')]
# [('film', 'http://www.wikidata.org/entity/Q262783'), ('filmName', "The Farmer's Daughter"), ('companyName', 'RKO Pictures')]
# [('film', 'http://www.wikidata.org/entity/Q22001133'), ('filmName', 'The Favourite'), ('companyName', 'Element Pictures')]
# [('film', 'http://www.wikidata.org/entity/Q22001133'), ('filmName', 'The Favourite'), ('companyName', 'Film4 Productions')]
# [('film', 'http://www.wikidata.org/entity/Q612540'), ('filmName', 'The Good Earth'), ('companyName', 'Metro-Goldwyn-Mayer')]
# [('film', 'http://www.wikidata.org/entity/Q470218'), ('filmName', 'The Great Ziegfeld'), ('companyName', 'Metro-Goldwyn-Mayer')]
# [('film', 'http://www.wikidata.org/entity/Q1141493'), ('filmName', 'The Heiress'), ('companyName', 'Paramount Pictures')]
# [('film', 'http://www.wikidata.org/entity/Q157044'), ('filmName', 'The Hours'), ('companyName', 'Paramount Pictures')]
# [('film', 'http://www.wikidata.org/entity/Q157044'), ('filmName', 'The Hours'), ('companyName', 'Miramax')]
# [('film', 'http://www.wikidata.org/entity/Q157044'), ('filmName', 'The Hours'), ('companyName', 'Scott Rudin Productions')]
# [('film', 'http://www.wikidata.org/entity/Q269810'), ('filmName', 'The Iron Lady'), ('companyName', 'Pathé')]
# [('film', 'http://www.wikidata.org/entity/Q269810'), ('filmName', 'The Iron Lady'), ('companyName', 'UK Film Council')]
# [('film', 'http://www.wikidata.org/entity/Q269810'), ('filmName', 'The Iron Lady'), ('companyName', 'Goldcrest Films')]
# [('film', 'http://www.wikidata.org/entity/Q269810'), ('filmName', 'The Iron Lady'), ('companyName', 'Film4 Productions')]
# [('film', 'http://www.wikidata.org/entity/Q1195311'), ('filmName', 'The Lion in Winter'), ('companyName', 'Embassy Pictures')]
# [('film', 'http://www.wikidata.org/entity/Q287536'), ('filmName', 'The Miracle Worker'), ('companyName', 'United Artists Corporation')]
# [('film', 'http://www.wikidata.org/entity/Q117315'), ('filmName', 'The Piano'), ('companyName', 'Ciby 2000')]
# [('film', 'http://www.wikidata.org/entity/Q117315'), ('filmName', 'The Piano'), ('companyName', 'Australian Film Commission')]
# [('film', 'http://www.wikidata.org/entity/Q117315'), ('filmName', 'The Piano'), ('companyName', 'Jan Chapman Productions')]
# [('film', 'http://www.wikidata.org/entity/Q667764'), ('filmName', 'The Prime of Miss Jean Brodie'), ('companyName', '20th Century Studios')]
# [('film', 'http://www.wikidata.org/entity/Q223367'), ('filmName', 'The Queen'), ('companyName', 'France 3')]
# [('film', 'http://www.wikidata.org/entity/Q223367'), ('filmName', 'The Queen'), ('companyName', 'ITV Studios')]
# [('film', 'http://www.wikidata.org/entity/Q223367'), ('filmName', 'The Queen'), ('companyName', 'Pathé')]
# [('film', 'http://www.wikidata.org/entity/Q223367'), ('filmName', 'The Queen'), ('companyName', 'Canal+')]
# [('film', 'http://www.wikidata.org/entity/Q223367'), ('filmName', 'The Queen'), ('companyName', 'BiM Distribuzione')]
# [('film', 'http://www.wikidata.org/entity/Q223367'), ('filmName', 'The Queen'), ('companyName', 'Granada Film')]
# [('film', 'http://www.wikidata.org/entity/Q159063'), ('filmName', 'The Reader'), ('companyName', 'Babelsberg Film GmbH')]
# [('film', 'http://www.wikidata.org/entity/Q159063'), ('filmName', 'The Reader'), ('companyName', 'The Weinstein Company')]
# [('film', 'http://www.wikidata.org/entity/Q634694'), ('filmName', 'The Rose Tattoo'), ('companyName', 'Paramount Pictures')]
# [('film', 'http://www.wikidata.org/entity/Q133654'), ('filmName', 'The Silence of the Lambs'), ('companyName', 'Orion Pictures')]
# [('film', 'http://www.wikidata.org/entity/Q940054'), ('filmName', 'The Sin of Madelon Claudet'), ('companyName', 'Metro-Goldwyn-Mayer')]
# [('film', 'http://www.wikidata.org/entity/Q669749'), ('filmName', 'The Song of Bernadette'), ('companyName', '20th Century Studios')]
# [('film', 'http://www.wikidata.org/entity/Q1379585'), ('filmName', 'The Three Faces of Eve'), ('companyName', '20th Century Studios')]
# [('film', 'http://www.wikidata.org/entity/Q24053277'), ('filmName', 'Three Billboards Outside Ebbing, Missouri'), ('companyName', 'Searchlight Pictures')]
# [('film', 'http://www.wikidata.org/entity/Q24053277'), ('filmName', 'Three Billboards Outside Ebbing, Missouri'), ('companyName', 'Film4 Productions')]
# [('film', 'http://www.wikidata.org/entity/Q24053277'), ('filmName', 'Three Billboards Outside Ebbing, Missouri'), ('companyName', 'Blueprint Pictures')]
# [('film', 'http://www.wikidata.org/entity/Q1627707'), ('filmName', 'To Each His Own'), ('companyName', 'Paramount Pictures')]
# [('film', 'http://www.wikidata.org/entity/Q128761'), ('filmName', 'Two Women'), ('companyName', 'Compagnia Cinematografica Champion')]
# [('film', 'http://www.wikidata.org/entity/Q154077'), ('filmName', 'Walk the Line'), ('companyName', '20th Century Studios')]
# [('film', 'http://www.wikidata.org/entity/Q325643'), ('filmName', "Who's Afraid of Virginia Woolf?"), ('companyName', 'Warner Bros.')]
# [('film', 'http://www.wikidata.org/entity/Q630132'), ('filmName', 'Women in Love'), ('companyName', 'Brandywine Productions')]
# 113

# %%
#The next step is to get only the companies (among television and film production companies) and how many movies that the producer won the award. 
queryString = """
SELECT DISTINCT ?company ?companyName (COUNT(*) AS ?awards) #I count how many times each company won. 
WHERE {

   # bind something
   # ?film wdt:P31 wd:Q11424 . #I get all the films. 
   # ?film wdt:P166 wd:Q103618. #Now I filter to only get the ones that won the award. 
   # ?film wdt:P272 ?company. 
   # ?company wdt:P31 ?type . #I get the type of the company into ?type
   
   #I get sure that the companies are Television producers companies or Film producers company. 
    #Television production company    #film production company 
   VALUES ?type {wd:Q10689397                    wd:Q1762059} 
   
   
   # get the label
   
   # ?company sc:name ?companyName. 
}
ORDER BY ?companyName
LIMIT 200
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('company', 'http://www.wikidata.org/entity/Q434841'), ('companyName', '20th Century Studios'), ('awards', '10')]
# [('company', 'http://www.wikidata.org/entity/Q4824145'), ('companyName', 'Australian Film Commission'), ('awards', '1')]
# [('company', 'http://www.wikidata.org/entity/Q971446'), ('companyName', 'BBC Film'), ('awards', '2')]
# [('company', 'http://www.wikidata.org/entity/Q100706708'), ('companyName', 'Babelsberg Film GmbH'), ('awards', '1')]
# [('company', 'http://www.wikidata.org/entity/Q3639301'), ('companyName', 'BiM Distribuzione'), ('awards', '1')]
# [('company', 'http://www.wikidata.org/entity/Q17386859'), ('companyName', 'Blueprint Pictures'), ('awards', '1')]
# [('company', 'http://www.wikidata.org/entity/Q1706678'), ('companyName', 'Brandywine Productions'), ('awards', '1')]
# [('company', 'http://www.wikidata.org/entity/Q622848'), ('companyName', 'Castle Rock Entertainment'), ('awards', '2')]
# [('company', 'http://www.wikidata.org/entity/Q4036210'), ('companyName', 'Ciby 2000'), ('awards', '1')]
# [('company', 'http://www.wikidata.org/entity/Q186941'), ('companyName', 'Columbia Pictures'), ('awards', '4')]
# [('company', 'http://www.wikidata.org/entity/Q5204823'), ('companyName', 'DEJ Productions'), ('awards', '1')]
# [('company', 'http://www.wikidata.org/entity/Q5369517'), ('companyName', 'Embassy Pictures'), ('awards', '2')]
# [('company', 'http://www.wikidata.org/entity/Q21729773'), ('companyName', 'Fantasy Films Productions'), ('awards', '1')]
# [('company', 'http://www.wikidata.org/entity/Q5448886'), ('companyName', 'Film4 Productions'), ('awards', '3')]
# [('company', 'http://www.wikidata.org/entity/Q2644123'), ('companyName', 'Fox Film'), ('awards', '1')]
# [('company', 'http://www.wikidata.org/entity/Q2138792'), ('companyName', 'Goldcrest Films'), ('awards', '1')]
# [('company', 'http://www.wikidata.org/entity/Q1506909'), ('companyName', 'Gracie Films'), ('awards', '2')]
# [('company', 'http://www.wikidata.org/entity/Q78788455'), ('companyName', 'Granada Film'), ('awards', '1')]
# [('company', 'http://www.wikidata.org/entity/Q3149951'), ('companyName', 'ITC Entertainment'), ('awards', '4')]
# [('company', 'http://www.wikidata.org/entity/Q5975134'), ('companyName', 'ITV Studios'), ('awards', '1')]
# [('company', 'http://www.wikidata.org/entity/Q17335626'), ('companyName', 'Jan Chapman Productions'), ('awards', '1')]
# [('company', 'http://www.wikidata.org/entity/Q6184876'), ('companyName', 'Jersey Group'), ('awards', '1')]
# [('company', 'http://www.wikidata.org/entity/Q1321379'), ('companyName', 'Lakeshore Entertainment'), ('awards', '1')]
# [('company', 'http://www.wikidata.org/entity/Q3841084'), ('companyName', 'Légende Entreprises'), ('awards', '1')]
# [('company', 'http://www.wikidata.org/entity/Q2407366'), ('companyName', 'Merchant Ivory Productions'), ('awards', '1')]
# [('company', 'http://www.wikidata.org/entity/Q179200'), ('companyName', 'Metro-Goldwyn-Mayer'), ('awards', '11')]
# [('company', 'http://www.wikidata.org/entity/Q16253226'), ('companyName', 'Mirage Enterprises'), ('awards', '1')]
# [('company', 'http://www.wikidata.org/entity/Q465449'), ('companyName', 'Miramax'), ('awards', '2')]
# [('company', 'http://www.wikidata.org/entity/Q80456350'), ('companyName', 'Okko Production'), ('awards', '1')]
# [('company', 'http://www.wikidata.org/entity/Q891732'), ('companyName', 'Orion Pictures'), ('awards', '2')]
# [('company', 'http://www.wikidata.org/entity/Q159846'), ('companyName', 'Paramount Pictures'), ('awards', '11')]
# [('company', 'http://www.wikidata.org/entity/Q1544011'), ('companyName', 'Pathé'), ('awards', '2')]
# [('company', 'http://www.wikidata.org/entity/Q11887890'), ('companyName', 'Phoenix Pictures'), ('awards', '1')]
# [('company', 'http://www.wikidata.org/entity/Q1983457'), ('companyName', 'PolyGram Filmed Entertainment'), ('awards', '2')]
# [('company', 'http://www.wikidata.org/entity/Q267282'), ('companyName', 'RKO Pictures'), ('awards', '4')]
# [('company', 'http://www.wikidata.org/entity/Q7295254'), ('companyName', 'Rastar'), ('awards', '1')]
# [('company', 'http://www.wikidata.org/entity/Q17295709'), ('companyName', 'Scott Rudin Productions'), ('awards', '1')]
# [('company', 'http://www.wikidata.org/entity/Q953040'), ('companyName', 'Searchlight Pictures'), ('awards', '4')]
# [('company', 'http://www.wikidata.org/entity/Q540122'), ('companyName', 'Selznick International Pictures'), ('awards', '1')]
# [('company', 'http://www.wikidata.org/entity/Q80456620'), ('companyName', 'Songbird Pictures'), ('awards', '1')]
# [('company', 'http://www.wikidata.org/entity/Q632323'), ('companyName', 'Summit Entertainment'), ('awards', '1')]
# [('company', 'http://www.wikidata.org/entity/Q80455720'), ('companyName', 'TF1 Films Production'), ('awards', '2')]
# [('company', 'http://www.wikidata.org/entity/Q80455410'), ('companyName', 'TF1 International'), ('awards', '1')]
# [('company', 'http://www.wikidata.org/entity/Q1138789'), ('companyName', 'The Weinstein Company'), ('awards', '2')]
# [('company', 'http://www.wikidata.org/entity/Q651454'), ('companyName', 'TriStar Pictures'), ('awards', '1')]
# [('company', 'http://www.wikidata.org/entity/Q219400'), ('companyName', 'United Artists Corporation'), ('awards', '2')]
# [('company', 'http://www.wikidata.org/entity/Q168383'), ('companyName', 'Universal Pictures'), ('awards', '2')]
# [('company', 'http://www.wikidata.org/entity/Q126399'), ('companyName', 'Warner Bros.'), ('awards', '9')]
# [('company', 'http://www.wikidata.org/entity/Q2060840'), ('companyName', 'Working Title Films'), ('awards', '2')]
# 49

# %% [markdown]
# Final query for this task

# %%
#The last step is to get only the ones with 5 or more
queryString = """
SELECT DISTINCT ?company ?companyName (COUNT(*) AS ?awards) #I count how many times each company won. 
WHERE {

   # bind something
   # ?film wdt:P31 wd:Q11424 . #I get all the films. 
   # ?film wdt:P166 wd:Q103618. #Now I filter to only get the ones that won the award. 
   # ?film wdt:P272 ?company. 
   # ?company wdt:P31 ?type . #I get the type of the company into ?type
   
   #I get sure that the companies are Television producers companies or Film producers company. 
    #Television production company    #film production company 
   VALUES ?type { wd:Q10689397                 wd:Q1762059} 
   
 
   # get the label
   
   # ?company sc:name ?companyName. 
}
GROUP BY ?company ?companyName 
HAVING (count(*)>=5) #With having I do that 
ORDER BY ?companyName
LIMIT 200
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('company', 'http://www.wikidata.org/entity/Q434841'), ('companyName', '20th Century Studios'), ('awards', '10')]
# [('company', 'http://www.wikidata.org/entity/Q179200'), ('companyName', 'Metro-Goldwyn-Mayer'), ('awards', '11')]
# [('company', 'http://www.wikidata.org/entity/Q159846'), ('companyName', 'Paramount Pictures'), ('awards', '11')]
# [('company', 'http://www.wikidata.org/entity/Q126399'), ('companyName', 'Warner Bros.'), ('awards', '9')]
# 4

# %% [markdown]
# # General instructions
#
# The goal of the project is to materialize a set of **exploratory workloads** over a real-world, large-scale,  open-domain KG: [WikiData](https://www.wikidata.org/wiki/Wikidata:Main_Page)
#
# An exploratory workload  is composed by a set of queries, where each query is related to the information obtained previously.
#
# An exploratory workload starts with a usually vague, open ended question, and does not assume the person issuing the workload has a clear understanding of the data contained in the target database or its structure.
#
# Remeber that:
#
# 1. All the queries must run in the python notebook
# 2. You can use classes and properties only if you find them via a SPARQL query that must be present in the notebook
# 3. You do not delete useless queries. Keep everything that is synthatically valid
#
# ```
# ?p <http://schema.org/name> ?name .
# ```
#
#     is the BGP returning a human-readable name of a property or a class in Wikidata.

# %%
## SETUP used later

from SPARQLWrapper import SPARQLWrapper, JSON


prefixString = """
##-7c962ddae6-##
PREFIX wd: <http://www.wikidata.org/entity/> 
PREFIX wdt: <http://www.wikidata.org/prop/direct/> 
PREFIX sc: <http://schema.org/>
"""

# select and construct queries
def run_query(queryString,verbose = True):
    to_run = prefixString + "\n" + queryString

    sparql = SPARQLWrapper("http://a256-gc1-03.srv.aau.dk:5820/sparql")
    sparql.setTimeout(300)
    sparql.setReturnFormat(JSON)
    sparql.setQuery(to_run)

    try :
        results = sparql.query()
        json_results = results.convert()
        if len(json_results['results']['bindings'])==0:
            print("Empty")
            return []
        array = []
        for bindings in json_results['results']['bindings']:
            app =  [ (var, value['value'])  for var, value in bindings.items() ] 
            if verbose:
                print( app)
            array.append(app)
        if verbose:
            print(len(array))
        return array

    except Exception as e :
        print("The operation failed", e)
    
# ASk queries
def run_ask_query(queryString):
    to_run = prefixString + "\n" + queryString

    sparql = SPARQLWrapper("http://a256-gc1-03.srv.aau.dk:5820/sparql")
    sparql.setTimeout(300)
    sparql.setReturnFormat(JSON)
    sparql.setQuery(to_run)

    try :
        return sparql.query().convert()

    except Exception as e :
        print("The operation failed", e)

# %% [markdown]
# # Movie Workflow Series ("Tv series HIMYM explorative search")
#
#
# Consider the following exploratory scenario:
#
#
# > we are interested in the TV series "How I met your mother" and we want to investigate the main aspects related to the actors and directors involved in the production, know the numerber of seasons and check what are the episodes which got the higher success/impact.
#
#
# ## Useful URIs for the current workflow
# The following are given:
#
# | IRI           | Description   | Role      |
# | -----------   | -----------   |-----------|
# | `wdt:P1647`   | subproperty   | predicate |
# | `wdt:P31`     | instance of   | predicate |
# | `wdt:P106`    | profession    | predicate |
# | `wdt:P279`    | subclass      | predicate |
# | `wdt:P4969`    | derivative work      | predicate |
# | `wd:Q147235` | How I met your mother        | node |
# | `wd:Q23831` | The Office (US)        | node |
#
#
#
# Also consider
#
# ```
# wd:Q23831 ?p ?obj .
# ```
#
# is the BGP to retrieve all **properties of The Office (US)**
#
# Please consider that when you return a resource, you should return the IRI and the label of the resource. In particular, when the task require you to identify a BGP the result set must always be a list of couples IRI - label.
#
# The workload should
#
# 1. Identify the BGP for tv series
#
# 2. Return the number of seasons and episodes per season of the tv series (the result set must be triples of season IRI, label and #episodes).
#
# 3. Get the number of episodes in which the cast members played a role. Who are the most present actors? (the result set must be a list of triples actor/actress IRI, label and #episodes)
#
# 4. Check who is the actor who acted in more films while working on "How I met your mother" (the result set must be a list of triples actor/actress IRI, label and #films).
#
# 5. Compare HIMYM with the tv series "The Office (US)" in terms of number of seasons, episods and cast members (the result set must be two elements -one for each tv series- of tv series IRI, label, #seasons, #episodes and #cast members).
#
# 6. Return how many of the actors who are members of the cast of the tv series have [Kavin Bacon number](https://en.wikipedia.org/wiki/Six_Degrees_of_Kevin_Bacon#:~:text=Kevin%20Bacon%20himself%20has%20a,Bacon%20number%20is%20N%2B1.) equal to 2 (the result set must be a list of couples actor/actress IRI and label).
#
# 7. Consider the actors who are members of the cast of HIMYM. Amongst the tv series which these actors acted return only those which received more than 2 awards (the result set must be triples of tv series IRI, label, #awards won).

# %% [markdown]
# ## Task 1
# Identify the BGP for tv series

# %%
# write your queries
# getting object properties of node 'HIMYM'
queryString = """
SELECT DISTINCT ?object_property ?label
WHERE
{
   wd:Q147235 ?object_property ?object.
   
   FILTER(!isLiteral(?object)).
   
   # ?object_property sc:name ?label.
}
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('object_property', 'http://www.wikidata.org/prop/direct/P2438'), ('label', 'narrator')]
# [('object_property', 'http://www.wikidata.org/prop/direct/P136'), ('label', 'genre')]
# [('object_property', 'http://www.wikidata.org/prop/direct/P138'), ('label', 'named after')]
# [('object_property', 'http://www.wikidata.org/prop/direct/P1411'), ('label', 'nominated for')]
# [('object_property', 'http://www.wikidata.org/prop/direct/P1424'), ('label', "topic's main template")]
# [('object_property', 'http://www.wikidata.org/prop/direct/P154'), ('label', 'logo image')]
# [('object_property', 'http://www.wikidata.org/prop/direct/P161'), ('label', 'cast member')]
# [('object_property', 'http://www.wikidata.org/prop/direct/P162'), ('label', 'producer')]
# [('object_property', 'http://www.wikidata.org/prop/direct/P166'), ('label', 'award received')]
# [('object_property', 'http://www.wikidata.org/prop/direct/P170'), ('label', 'creator')]
# [('object_property', 'http://www.wikidata.org/prop/direct/P18'), ('label', 'image')]
# [('object_property', 'http://www.wikidata.org/prop/direct/P1811'), ('label', 'list of episodes')]
# [('object_property', 'http://www.wikidata.org/prop/direct/P1881'), ('label', 'list of characters')]
# [('object_property', 'http://www.wikidata.org/prop/direct/P2061'), ('label', 'aspect ratio')]
# [('object_property', 'http://www.wikidata.org/prop/direct/P2670'), ('label', 'has parts of the class')]
# [('object_property', 'http://www.wikidata.org/prop/direct/P272'), ('label', 'production company')]
# [('object_property', 'http://www.wikidata.org/prop/direct/P31'), ('label', 'instance of')]
# [('object_property', 'http://www.wikidata.org/prop/direct/P364'), ('label', 'original language of film or TV show')]
# [('object_property', 'http://www.wikidata.org/prop/direct/P437'), ('label', 'distribution format')]
# [('object_property', 'http://www.wikidata.org/prop/direct/P449'), ('label', 'original broadcaster')]
# [('object_property', 'http://www.wikidata.org/prop/direct/P495'), ('label', 'country of origin')]
# [('object_property', 'http://www.wikidata.org/prop/direct/P4969'), ('label', 'derivative work')]
# [('object_property', 'http://www.wikidata.org/prop/direct/P527'), ('label', 'has part')]
# [('object_property', 'http://www.wikidata.org/prop/direct/P58'), ('label', 'screenwriter')]
# [('object_property', 'http://www.wikidata.org/prop/direct/P674'), ('label', 'characters')]
# [('object_property', 'http://www.wikidata.org/prop/direct/P750'), ('label', 'distributed by')]
# [('object_property', 'http://www.wikidata.org/prop/direct/P840'), ('label', 'narrative location')]
# [('object_property', 'http://www.wikidata.org/prop/direct/P856'), ('label', 'official website')]
# [('object_property', 'http://www.wikidata.org/prop/direct/P86'), ('label', 'composer')]
# [('object_property', 'http://www.wikidata.org/prop/direct/P910'), ('label', "topic's main category")]
# [('object_property', 'http://www.wikidata.org/prop/direct/P4312'), ('label', 'camera setup')]
# [('object_property', 'http://www.wikidata.org/prop/direct/P7501'), ('label', 'audio system')]
# [('object_property', 'http://www.wikidata.org/prop/direct/P725'), ('label', 'voice actor')]
# 33

# %%
# getting data properties of node 'HIMYM'
queryString = """
SELECT DISTINCT ?data_property ?label
WHERE
{
   wd:Q147235 ?data_property ?object.
   
   FILTER(isLiteral(?object))
   
   # ?data_property sc:name ?label.
}
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('data_property', 'http://www.wikidata.org/prop/direct/P1113'), ('label', 'number of episodes')]
# [('data_property', 'http://www.wikidata.org/prop/direct/P1258'), ('label', 'Rotten Tomatoes ID')]
# [('data_property', 'http://www.wikidata.org/prop/direct/P1267'), ('label', 'AlloCiné series ID')]
# [('data_property', 'http://www.wikidata.org/prop/direct/P1476'), ('label', 'title')]
# [('data_property', 'http://www.wikidata.org/prop/direct/P1562'), ('label', 'AllMovie title ID')]
# [('data_property', 'http://www.wikidata.org/prop/direct/P1712'), ('label', 'Metacritic ID')]
# [('data_property', 'http://www.wikidata.org/prop/direct/P1874'), ('label', 'Netflix ID')]
# [('data_property', 'http://www.wikidata.org/prop/direct/P1922'), ('label', 'first line')]
# [('data_property', 'http://www.wikidata.org/prop/direct/P2002'), ('label', 'Twitter username')]
# [('data_property', 'http://www.wikidata.org/prop/direct/P2047'), ('label', 'duration')]
# [('data_property', 'http://www.wikidata.org/prop/direct/P214'), ('label', 'VIAF ID')]
# [('data_property', 'http://www.wikidata.org/prop/direct/P227'), ('label', 'GND ID')]
# [('data_property', 'http://www.wikidata.org/prop/direct/P2373'), ('label', 'Genius artist ID')]
# [('data_property', 'http://www.wikidata.org/prop/direct/P2437'), ('label', 'number of seasons')]
# [('data_property', 'http://www.wikidata.org/prop/direct/P244'), ('label', 'Library of Congress authority ID')]
# [('data_property', 'http://www.wikidata.org/prop/direct/P2529'), ('label', 'ČSFD film ID')]
# [('data_property', 'http://www.wikidata.org/prop/direct/P2581'), ('label', 'BabelNet ID')]
# [('data_property', 'http://www.wikidata.org/prop/direct/P2603'), ('label', 'Kinopoisk film ID')]
# [('data_property', 'http://www.wikidata.org/prop/direct/P2638'), ('label', 'TV.com ID')]
# [('data_property', 'http://www.wikidata.org/prop/direct/P2703'), ('label', 'BFI National Archive work ID')]
# [('data_property', 'http://www.wikidata.org/prop/direct/P2704'), ('label', 'EIDR content ID')]
# [('data_property', 'http://www.wikidata.org/prop/direct/P3121'), ('label', 'Epguides ID')]
# [('data_property', 'http://www.wikidata.org/prop/direct/P3138'), ('label', 'OFDb film ID')]
# [('data_property', 'http://www.wikidata.org/prop/direct/P3302'), ('label', 'Open Media Database film ID')]
# [('data_property', 'http://www.wikidata.org/prop/direct/P3417'), ('label', 'Quora topic ID')]
# [('data_property', 'http://www.wikidata.org/prop/direct/P345'), ('label', 'IMDb ID')]
# [('data_property', 'http://www.wikidata.org/prop/direct/P3553'), ('label', 'Zhihu topic ID')]
# [('data_property', 'http://www.wikidata.org/prop/direct/P373'), ('label', 'Commons category')]
# [('data_property', 'http://www.wikidata.org/prop/direct/P4073'), ('label', 'Fandom wiki ID')]
# [('data_property', 'http://www.wikidata.org/prop/direct/P4438'), ('label', 'BFI Films, TV and people ID')]
# [('data_property', 'http://www.wikidata.org/prop/direct/P4665'), ('label', 'CineMagia title ID')]
# [('data_property', 'http://www.wikidata.org/prop/direct/P4835'), ('label', 'TheTVDB.com series ID')]
# [('data_property', 'http://www.wikidata.org/prop/direct/P4983'), ('label', 'TMDb TV series ID')]
# [('data_property', 'http://www.wikidata.org/prop/direct/P5032'), ('label', 'Filmweb.pl film ID')]
# [('data_property', 'http://www.wikidata.org/prop/direct/P5099'), ('label', 'Il mondo dei doppiatori ID')]
# [('data_property', 'http://www.wikidata.org/prop/direct/P5327'), ('label', 'fernsehserien.de ID')]
# [('data_property', 'http://www.wikidata.org/prop/direct/P580'), ('label', 'start time')]
# [('data_property', 'http://www.wikidata.org/prop/direct/P582'), ('label', 'end time')]
# [('data_property', 'http://www.wikidata.org/prop/direct/P5925'), ('label', 'Moviepilot.de series ID')]
# [('data_property', 'http://www.wikidata.org/prop/direct/P646'), ('label', 'Freebase ID')]
# [('data_property', 'http://www.wikidata.org/prop/direct/P6760'), ('label', 'Know Your Meme ID')]
# [('data_property', 'http://www.wikidata.org/prop/direct/P6839'), ('label', 'TV Tropes identifier')]
# [('data_property', 'http://www.wikidata.org/prop/direct/P7299'), ('label', 'MUBI film ID')]
# [('data_property', 'http://www.wikidata.org/prop/direct/P8013'), ('label', 'Trakt.tv ID')]
# [('data_property', 'http://www.wikidata.org/prop/direct/P8278'), ('label', 'serial identifier on SerialZone')]
# [('data_property', 'http://www.wikidata.org/prop/direct/P8687'), ('label', 'social media followers')]
# [('data_property', 'http://www.wikidata.org/prop/direct/P905'), ('label', 'PORT film ID')]
# [('data_property', 'http://www.wikidata.org/prop/direct/P9629'), ('label', 'Armeniapedia ID')]
# [('data_property', 'http://www.wikidata.org/prop/direct/P4784'), ('label', 'Movieplayer TV-series ID')]
# [('data_property', 'http://www.wikidata.org/prop/direct/P4834'), ('label', 'Deutsche Synchronkartei series ID')]
# [('data_property', 'http://www.wikidata.org/prop/direct/P6467'), ('label', 'Hulu series ID')]
# [('data_property', 'http://www.wikidata.org/prop/direct/P6643'), ('label', 'TV Spielfilm series ID')]
# [('data_property', 'http://www.wikidata.org/prop/direct/P7107'), ('label', 'LezWatch.TV show ID')]
# [('data_property', 'http://www.wikidata.org/prop/direct/P7596'), ('label', 'Disney+ series ID')]
# [('data_property', 'http://www.wikidata.org/prop/direct/P9751'), ('label', 'Apple TV show ID')]
# 55

# %% [markdown]
# Final query for this task

# %%
# write your final query
queryString = """
SELECT ?object ?label
WHERE
{
   wd:Q147235 wdt:P31 ?object.
   
   # ?object sc:name ?label.
}
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('object', 'http://www.wikidata.org/entity/Q5398426'), ('label', 'television series')]
# 1

# %% [markdown]
# ## Task 2
# Return the number of seasons and episodes per season of the tv series (the result set must be triples of season IRI, label and #episodes).

# %%
# s:'HIMYM' p:'list of episodes' o:what node?
queryString = """
SELECT ?object ?label
WHERE
{
   wd:Q147235 wdt:P1811 ?object.
   
   # ?object sc:name ?label.
}
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('object', 'http://www.wikidata.org/entity/Q785891'), ('label', 'list of How I Met Your Mother episodes')]
# 1

# %%
# getting data properties of node 'list of How I met your mother episodes'
queryString = """
SELECT DISTINCT ?data_property ?label
WHERE
{
   wd:Q785891 ?data_property ?object.
   
   FILTER(isLiteral(?object)).
   
   # ?data_property sc:name ?label.
}
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('data_property', 'http://www.wikidata.org/prop/direct/P3921'), ('label', 'Wikidata SPARQL query equivalent')]
# 1

# %%
# getting only number of seasons of node 'HIMYM'
queryString = """
SELECT ?num_season
WHERE
{
   wd:Q147235 wdt:P2437 ?num_season.
}
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('num_season', '9')]
# 1

# %%
# getting only number of episodes of node 'HIMYM'
queryString = """
SELECT ?num_episode
WHERE
{
   wd:Q147235 wdt:P1113 ?num_episode.
}
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('num_episode', '208')]
# 1

# %%
# checking 'has parts of the class' object property of node 'HIMYM'
queryString = """
SELECT ?object ?label
WHERE
{
   wd:Q147235 wdt:P2670 ?object.
   
   # ?object sc:name ?label.
}
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('object', 'http://www.wikidata.org/entity/Q21664088'), ('label', 'two-part episode')]
# 1

# %%
# checking 'has part' object property of node 'HIMYM'
queryString = """
SELECT ?object ?label
WHERE
{
   wd:Q147235 wdt:P527 ?object.
   
   # ?object sc:name ?label.
}
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('object', 'http://www.wikidata.org/entity/Q2438066'), ('label', 'How I Met Your Mother, season 6')]
# [('object', 'http://www.wikidata.org/entity/Q2715578'), ('label', 'How I Met Your Mother, season 1')]
# [('object', 'http://www.wikidata.org/entity/Q13567027'), ('label', 'How I Met Your Mother, season 9')]
# [('object', 'http://www.wikidata.org/entity/Q2567330'), ('label', 'How I Met Your Mother, season 4')]
# [('object', 'http://www.wikidata.org/entity/Q338715'), ('label', 'How I Met Your Mother, season 8')]
# [('object', 'http://www.wikidata.org/entity/Q582332'), ('label', 'How I Met Your Mother, season 5')]
# [('object', 'http://www.wikidata.org/entity/Q3468515'), ('label', 'How I Met Your Mother, season 2')]
# [('object', 'http://www.wikidata.org/entity/Q2555117'), ('label', 'How I Met Your Mother, season 3')]
# [('object', 'http://www.wikidata.org/entity/Q2472427'), ('label', 'How I Met Your Mother, season 7')]
# 9

# %%
# getting object/data properties of an arbitrary season (9)
queryString = """
SELECT DISTINCT ?property ?label
WHERE
{
   wd:Q13567027 ?property ?object.
   
   # ?property sc:name ?label.
}
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('property', 'http://www.wikidata.org/prop/direct/P1113'), ('label', 'number of episodes')]
# [('property', 'http://www.wikidata.org/prop/direct/P1258'), ('label', 'Rotten Tomatoes ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1712'), ('label', 'Metacritic ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P179'), ('label', 'part of the series')]
# [('property', 'http://www.wikidata.org/prop/direct/P2529'), ('label', 'ČSFD film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2638'), ('label', 'TV.com ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2704'), ('label', 'EIDR content ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P31'), ('label', 'instance of')]
# [('property', 'http://www.wikidata.org/prop/direct/P3302'), ('label', 'Open Media Database film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P364'), ('label', 'original language of film or TV show')]
# [('property', 'http://www.wikidata.org/prop/direct/P437'), ('label', 'distribution format')]
# [('property', 'http://www.wikidata.org/prop/direct/P527'), ('label', 'has part')]
# [('property', 'http://www.wikidata.org/prop/direct/P580'), ('label', 'start time')]
# [('property', 'http://www.wikidata.org/prop/direct/P582'), ('label', 'end time')]
# [('property', 'http://www.wikidata.org/prop/direct/P646'), ('label', 'Freebase ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P750'), ('label', 'distributed by')]
# [('property', 'http://www.wikidata.org/prop/direct/P856'), ('label', 'official website')]
# [('property', 'http://www.wikidata.org/prop/direct/P2684'), ('label', 'Kijkwijzer rating')]
# [('property', 'http://www.wikidata.org/prop/direct/P6381'), ('label', 'iTunes TV season ID')]
# 19

# %%
# checking 'number of episodes' property of an arbitrary season (9)
queryString = """
SELECT ?num_episode_season_9
WHERE
{
   wd:Q13567027 wdt:P1113 ?num_episode_season_9.
}
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('num_episode_season_9', '24')]
# 1

# %% [markdown]
# Final query for this task

# %%
# write your final query
queryString = """
SELECT ?season_iri ?label ?num_episode
WHERE
{
   wd:Q147235 wdt:P527 ?season_iri.
   # ?season_iri wdt:P1113 ?num_episode.
   
   # ?season_iri sc:name ?label.
}
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('season_iri', 'http://www.wikidata.org/entity/Q2438066'), ('label', 'How I Met Your Mother, season 6'), ('num_episode', '24')]
# [('season_iri', 'http://www.wikidata.org/entity/Q2715578'), ('label', 'How I Met Your Mother, season 1'), ('num_episode', '22')]
# [('season_iri', 'http://www.wikidata.org/entity/Q13567027'), ('label', 'How I Met Your Mother, season 9'), ('num_episode', '24')]
# [('season_iri', 'http://www.wikidata.org/entity/Q2567330'), ('label', 'How I Met Your Mother, season 4'), ('num_episode', '24')]
# [('season_iri', 'http://www.wikidata.org/entity/Q338715'), ('label', 'How I Met Your Mother, season 8'), ('num_episode', '24')]
# [('season_iri', 'http://www.wikidata.org/entity/Q582332'), ('label', 'How I Met Your Mother, season 5'), ('num_episode', '24')]
# [('season_iri', 'http://www.wikidata.org/entity/Q3468515'), ('label', 'How I Met Your Mother, season 2'), ('num_episode', '22')]
# [('season_iri', 'http://www.wikidata.org/entity/Q2555117'), ('label', 'How I Met Your Mother, season 3'), ('num_episode', '20')]
# [('season_iri', 'http://www.wikidata.org/entity/Q2472427'), ('label', 'How I Met Your Mother, season 7'), ('num_episode', '24')]
# 9

# %% [markdown]
# ## Task 3
# Get the number of episodes in which the cast members played a role. Who are the most present actors? (the result set must be a list of triples actor/actress IRI, label and #episodes)

# %%
# write your queries
# checking 'cast member' object property of node 'HIMYM' (actual count: 480)
queryString = """
SELECT DISTINCT ?object ?label
WHERE
{
   wd:Q147235 wdt:P161 ?object.
   
   # ?object sc:name ?label.
}
LIMIT 50
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('object', 'http://www.wikidata.org/entity/Q465556'), ('label', 'Annie Ilonzeh')]
# [('object', 'http://www.wikidata.org/entity/Q269891'), ('label', 'Julianna Guill')]
# [('object', 'http://www.wikidata.org/entity/Q4888924'), ('label', 'Benjamin Koldyke')]
# [('object', 'http://www.wikidata.org/entity/Q446031'), ('label', 'Nikki Griffin')]
# [('object', 'http://www.wikidata.org/entity/Q312705'), ('label', 'John Cho')]
# [('object', 'http://www.wikidata.org/entity/Q469579'), ('label', 'Mircea Monroe')]
# [('object', 'http://www.wikidata.org/entity/Q516659'), ('label', 'Virginia Williams')]
# [('object', 'http://www.wikidata.org/entity/Q522856'), ('label', 'Kate Micucci')]
# [('object', 'http://www.wikidata.org/entity/Q200566'), ('label', 'Cobie Smulders')]
# [('object', 'http://www.wikidata.org/entity/Q435839'), ('label', 'Ashley Williams')]
# [('object', 'http://www.wikidata.org/entity/Q446481'), ('label', 'Harvey Fierstein')]
# [('object', 'http://www.wikidata.org/entity/Q2040329'), ('label', 'Hayes MacArthur')]
# [('object', 'http://www.wikidata.org/entity/Q596953'), ('label', 'Phil Simms')]
# [('object', 'http://www.wikidata.org/entity/Q926420'), ('label', 'Robbie Amell')]
# [('object', 'http://www.wikidata.org/entity/Q929985'), ('label', 'Alex Trebek')]
# [('object', 'http://www.wikidata.org/entity/Q234715'), ('label', 'Jamie-Lynn Sigler')]
# [('object', 'http://www.wikidata.org/entity/Q215546'), ('label', 'Carrie Underwood')]
# [('object', 'http://www.wikidata.org/entity/Q2914539'), ('label', 'Jeff Probst')]
# [('object', 'http://www.wikidata.org/entity/Q289330'), ('label', 'Erin Cardillo')]
# [('object', 'http://www.wikidata.org/entity/Q3306283'), ('label', 'Dwight Hicks')]
# [('object', 'http://www.wikidata.org/entity/Q3859348'), ('label', 'Misti Traya')]
# [('object', 'http://www.wikidata.org/entity/Q459839'), ('label', "Brooke D'Orsay")]
# [('object', 'http://www.wikidata.org/entity/Q5087461'), ('label', 'Chasty Ballesteros')]
# [('object', 'http://www.wikidata.org/entity/Q5072641'), ('label', 'Chantelle Barry')]
# [('object', 'http://www.wikidata.org/entity/Q1332676'), ('label', 'William Schallert')]
# [('object', 'http://www.wikidata.org/entity/Q11975'), ('label', 'Britney Spears')]
# [('object', 'http://www.wikidata.org/entity/Q260184'), ('label', 'Eva Amurri')]
# [('object', 'http://www.wikidata.org/entity/Q291024'), ('label', 'Moon Zappa')]
# [('object', 'http://www.wikidata.org/entity/Q337557'), ('label', 'J. P. Manoux')]
# [('object', 'http://www.wikidata.org/entity/Q40715'), ('label', 'Jennifer Lopez')]
# [('object', 'http://www.wikidata.org/entity/Q512376'), ('label', 'Suzy Nakamura')]
# [('object', 'http://www.wikidata.org/entity/Q560516'), ('label', 'Andrew Rannells')]
# [('object', 'http://www.wikidata.org/entity/Q174346'), ('label', 'Katie Holmes')]
# [('object', 'http://www.wikidata.org/entity/Q488335'), ('label', 'Kevin Michael Richardson')]
# [('object', 'http://www.wikidata.org/entity/Q594265'), ('label', 'Neil Jackson')]
# [('object', 'http://www.wikidata.org/entity/Q220949'), ('label', 'Rachel Bilson')]
# [('object', 'http://www.wikidata.org/entity/Q236766'), ('label', 'Maggie Wheeler')]
# [('object', 'http://www.wikidata.org/entity/Q255293'), ('label', 'Geoff Stults')]
# [('object', 'http://www.wikidata.org/entity/Q2942050'), ('label', 'Catherine Reitman')]
# [('object', 'http://www.wikidata.org/entity/Q444480'), ('label', 'Elizabeth Bogush')]
# [('object', 'http://www.wikidata.org/entity/Q943613'), ('label', 'Samm Levine')]
# [('object', 'http://www.wikidata.org/entity/Q1388143'), ('label', 'Gregory Michael')]
# [('object', 'http://www.wikidata.org/entity/Q229728'), ('label', 'Sarah Chalke')]
# [('object', 'http://www.wikidata.org/entity/Q233042'), ('label', 'Nancy Travis')]
# [('object', 'http://www.wikidata.org/entity/Q270260'), ('label', 'Chelan Simmons')]
# [('object', 'http://www.wikidata.org/entity/Q4491707'), ('label', 'Olga Fonda')]
# [('object', 'http://www.wikidata.org/entity/Q634684'), ('label', 'Roger Bart')]
# [('object', 'http://www.wikidata.org/entity/Q963626'), ('label', 'Paul Shaffer')]
# [('object', 'http://www.wikidata.org/entity/Q968718'), ('label', 'Bruce Gray')]
# [('object', 'http://www.wikidata.org/entity/Q130549'), ('label', 'Tracey Ullman')]
# 50

# %%
# getting object/data properties of an arbitrary actress (Annie Ilonzeh) taken from last query's output
queryString = """
SELECT DISTINCT ?property ?label
WHERE
{
   wd:Q465556 ?property ?object.
   
   # ?property sc:name ?label.
}
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('property', 'http://www.wikidata.org/prop/direct/P106'), ('label', 'occupation')]
# [('property', 'http://www.wikidata.org/prop/direct/P1266'), ('label', 'AlloCiné person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P172'), ('label', 'ethnic group')]
# [('property', 'http://www.wikidata.org/prop/direct/P19'), ('label', 'place of birth')]
# [('property', 'http://www.wikidata.org/prop/direct/P2002'), ('label', 'Twitter username')]
# [('property', 'http://www.wikidata.org/prop/direct/P2003'), ('label', 'Instagram username')]
# [('property', 'http://www.wikidata.org/prop/direct/P2013'), ('label', 'Facebook ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2019'), ('label', 'AllMovie person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2031'), ('label', 'work period (start)')]
# [('property', 'http://www.wikidata.org/prop/direct/P21'), ('label', 'sex or gender')]
# [('property', 'http://www.wikidata.org/prop/direct/P214'), ('label', 'VIAF ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P227'), ('label', 'GND ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2435'), ('label', 'PORT person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2604'), ('label', 'Kinopoisk person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2605'), ('label', 'ČSFD person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P27'), ('label', 'country of citizenship')]
# [('property', 'http://www.wikidata.org/prop/direct/P31'), ('label', 'instance of')]
# [('property', 'http://www.wikidata.org/prop/direct/P3142'), ('label', 'EDb person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P345'), ('label', 'IMDb ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4332'), ('label', 'Deutsche Synchronkartei actor ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4657'), ('label', 'The Numbers person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4666'), ('label', 'CineMagia person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4985'), ('label', 'TMDb person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5008'), ('label', 'on focus list of Wikimedia project')]
# [('property', 'http://www.wikidata.org/prop/direct/P5284'), ('label', 'Douban movie celebrity ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P569'), ('label', 'date of birth')]
# [('property', 'http://www.wikidata.org/prop/direct/P646'), ('label', 'Freebase ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P69'), ('label', 'educated at')]
# [('property', 'http://www.wikidata.org/prop/direct/P735'), ('label', 'given name')]
# [('property', 'http://www.wikidata.org/prop/direct/P7859'), ('label', 'WorldCat Identities ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P8125'), ('label', 'Fandango person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P8687'), ('label', 'social media followers')]
# [('property', 'http://www.wikidata.org/prop/direct/P7105'), ('label', 'LezWatch.TV actor ID')]
# 33

# %%
# checking 'has part' object property of an arbitrary season (9)
queryString = """
SELECT ?object ?label
WHERE
{
   wd:Q13567027 wdt:P527 ?object.
   
   # ?object sc:name ?label.
}
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('object', 'http://www.wikidata.org/entity/Q15846036'), ('label', 'Unpause')]
# [('object', 'http://www.wikidata.org/entity/Q15846040'), ('label', 'Slapsgiving 3: Slappointment in Slapmarra')]
# [('object', 'http://www.wikidata.org/entity/Q15919313'), ('label', 'Rally')]
# [('object', 'http://www.wikidata.org/entity/Q15983482'), ('label', 'How Your Mother Met Me')]
# [('object', 'http://www.wikidata.org/entity/Q15983495'), ('label', 'Sunrise')]
# [('object', 'http://www.wikidata.org/entity/Q16738646'), ('label', 'Daisy')]
# [('object', 'http://www.wikidata.org/entity/Q16744027'), ('label', 'The Poker Game')]
# [('object', 'http://www.wikidata.org/entity/Q16745693'), ('label', 'Gary Blauman')]
# [('object', 'http://www.wikidata.org/entity/Q16746127'), ('label', 'The Locket')]
# [('object', 'http://www.wikidata.org/entity/Q16746145'), ('label', 'Coming Back')]
# [('object', 'http://www.wikidata.org/entity/Q16746190'), ('label', 'The Broken Code')]
# [('object', 'http://www.wikidata.org/entity/Q16746202'), ('label', 'Last Time in New York')]
# [('object', 'http://www.wikidata.org/entity/Q16746203'), ('label', 'No Questions Asked')]
# [('object', 'http://www.wikidata.org/entity/Q16746204'), ('label', 'Knight Vision')]
# [('object', 'http://www.wikidata.org/entity/Q16746250'), ('label', 'The Lighthouse')]
# [('object', 'http://www.wikidata.org/entity/Q16746251'), ('label', 'Mom and Dad')]
# [('object', 'http://www.wikidata.org/entity/Q16746255'), ('label', 'Platonish')]
# [('object', 'http://www.wikidata.org/entity/Q16746256'), ('label', 'Bass Player Wanted')]
# [('object', 'http://www.wikidata.org/entity/Q16746317'), ('label', 'Bedtime Stories')]
# [('object', 'http://www.wikidata.org/entity/Q16746318'), ('label', 'The Rehearsal Dinner')]
# [('object', 'http://www.wikidata.org/entity/Q16746365'), ('label', 'Vesuvius')]
# [('object', 'http://www.wikidata.org/entity/Q16746366'), ('label', 'The End of the Aisle')]
# [('object', 'http://www.wikidata.org/entity/Q48986965'), ('label', 'Last Forever, Part I')]
# [('object', 'http://www.wikidata.org/entity/Q48986998'), ('label', 'Last Forever, Part II')]
# 24

# %%
# getting object/data properties of an arbitrary episode (Unpause) of an arbitrary season (9)
queryString = """
SELECT DISTINCT ?property ?label
WHERE
{
   wd:Q15846036 ?property ?object.
   
   # ?property sc:name ?label.
}
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('property', 'http://www.wikidata.org/prop/direct/P1258'), ('label', 'Rotten Tomatoes ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1476'), ('label', 'title')]
# [('property', 'http://www.wikidata.org/prop/direct/P155'), ('label', 'follows')]
# [('property', 'http://www.wikidata.org/prop/direct/P156'), ('label', 'followed by')]
# [('property', 'http://www.wikidata.org/prop/direct/P1562'), ('label', 'AllMovie title ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P179'), ('label', 'part of the series')]
# [('property', 'http://www.wikidata.org/prop/direct/P2529'), ('label', 'ČSFD film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2638'), ('label', 'TV.com ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2704'), ('label', 'EIDR content ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P31'), ('label', 'instance of')]
# [('property', 'http://www.wikidata.org/prop/direct/P3212'), ('label', 'ISAN')]
# [('property', 'http://www.wikidata.org/prop/direct/P3302'), ('label', 'Open Media Database film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P345'), ('label', 'IMDb ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P364'), ('label', 'original language of film or TV show')]
# [('property', 'http://www.wikidata.org/prop/direct/P4665'), ('label', 'CineMagia title ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4908'), ('label', 'season')]
# [('property', 'http://www.wikidata.org/prop/direct/P57'), ('label', 'director')]
# [('property', 'http://www.wikidata.org/prop/direct/P577'), ('label', 'publication date')]
# [('property', 'http://www.wikidata.org/prop/direct/P646'), ('label', 'Freebase ID')]
# 19

# %%
# getting all 'cast member' of an arbitrary episode (Unpause) of an arbitrary season (9)
queryString = """
SELECT ?actor_iri ?label
WHERE
{
   wd:Q15846036 wdt:P161 ?actor_iri.
   
   # ?actor_iri sc:name ?label.
}
LIMIT 50
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# Empty

# %%
# getting all 'cast member' of a different episode (Rally) of the same season (9) to check whether 
# this one also results as empty or not
queryString = """
SELECT ?actor_iri ?label
WHERE
{
   wd:Q15919313 wdt:P161 ?actor_iri.
   
   # ?actor_iri sc:name ?label.
}
LIMIT 50
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# Empty

# %%
# checking 'has part' object property of an arbitrary season (7)
queryString = """
SELECT ?object ?label
WHERE
{
   wd:Q2472427 wdt:P527 ?object.
   
   # ?object sc:name ?label.
}
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('object', 'http://www.wikidata.org/entity/Q6372650'), ('label', 'Karma')]
# [('object', 'http://www.wikidata.org/entity/Q7720231'), ('label', 'The Broath')]
# [('object', 'http://www.wikidata.org/entity/Q5582491'), ('label', 'Good Crazy')]
# [('object', 'http://www.wikidata.org/entity/Q7065844'), ('label', "Now We're Even")]
# [('object', 'http://www.wikidata.org/entity/Q7842088'), ('label', 'Trilogy Time')]
# [('object', 'http://www.wikidata.org/entity/Q11158351'), ('label', 'Mystery vs. History')]
# [('object', 'http://www.wikidata.org/entity/Q16745474'), ('label', 'Noretta')]
# [('object', 'http://www.wikidata.org/entity/Q16745507'), ('label', 'The Burning Beekeeper')]
# [('object', 'http://www.wikidata.org/entity/Q4638335'), ('label', '46 Minutes')]
# [('object', 'http://www.wikidata.org/entity/Q48984467'), ('label', "The Magician's Code (Part 1)")]
# [('object', 'http://www.wikidata.org/entity/Q48984493'), ('label', "The Magician's Code (Part 2)")]
# [('object', 'http://www.wikidata.org/entity/Q5281325'), ('label', 'Disaster Averted')]
# [('object', 'http://www.wikidata.org/entity/Q5311567'), ('label', 'Ducky Tie')]
# [('object', 'http://www.wikidata.org/entity/Q5446960'), ('label', 'Field Trip')]
# [('object', 'http://www.wikidata.org/entity/Q7044816'), ('label', 'No Pressure')]
# [('object', 'http://www.wikidata.org/entity/Q7661695'), ('label', 'Symphony of Illumination')]
# [('object', 'http://www.wikidata.org/entity/Q7676106'), ('label', 'Tailgate')]
# [('object', 'http://www.wikidata.org/entity/Q7716739'), ('label', 'The Best Man')]
# [('object', 'http://www.wikidata.org/entity/Q7731094'), ('label', 'The Drunk Train')]
# [('object', 'http://www.wikidata.org/entity/Q7753043'), ('label', 'The Naked Truth')]
# [('object', 'http://www.wikidata.org/entity/Q7759768'), ('label', 'The Rebound Girl')]
# [('object', 'http://www.wikidata.org/entity/Q7764861'), ('label', 'The Slutty Pumpkin Returns')]
# [('object', 'http://www.wikidata.org/entity/Q7766552'), ('label', 'The Stinson Missile Crisis')]
# [('object', 'http://www.wikidata.org/entity/Q7800623'), ('label', 'Tick Tick Tick')]
# 24

# %%
# getting all 'cast member' of an arbitrary episode (Karma) of a different season (7) to check whether 
# this one also results as empty or not

# this one is not empty; so, it seems like some episodes do not have their cast members listed
queryString = """
SELECT ?actor_iri ?label
WHERE
{
   wd:Q5446960 wdt:P161 ?actor_iri.
   
   # ?actor_iri sc:name ?label.
}
LIMIT 50
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('actor_iri', 'http://www.wikidata.org/entity/Q200566'), ('label', 'Cobie Smulders')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q1189102'), ('label', 'Nazanin Boniadi')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q220536'), ('label', 'Kal Penn')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q485310'), ('label', 'Neil Patrick Harris')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q223455'), ('label', 'Josh Radnor')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q199927'), ('label', 'Alyson Hannigan')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q202304'), ('label', 'Jason Segel')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q329744'), ('label', 'Martin Short')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q333544'), ('label', 'Bob Saget')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q3109076'), ('label', 'Jay Acovone')]
# 10

# %% [markdown]
# Final query for this task

# %%
# write your final query
queryString = """
SELECT ?actor_iri ?label (COUNT(*) AS ?num_episode)
WHERE
{
   wd:Q147235 wdt:P527 ?season.
   # ?season wdt:P527 ?episode.
   # ?episode wdt:P161 ?actor_iri.
   
   # ?actor_iri sc:name ?label.
}
GROUP BY ?actor_iri ?label
ORDER BY DESC(?num_episode)
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('actor_iri', 'http://www.wikidata.org/entity/Q223455'), ('label', 'Josh Radnor'), ('num_episode', '145')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q485310'), ('label', 'Neil Patrick Harris'), ('num_episode', '145')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q200566'), ('label', 'Cobie Smulders'), ('num_episode', '145')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q202304'), ('label', 'Jason Segel'), ('num_episode', '145')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q199927'), ('label', 'Alyson Hannigan'), ('num_episode', '143')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q333544'), ('label', 'Bob Saget'), ('num_episode', '142')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q229914'), ('label', 'Lyndsy Fonseca'), ('num_episode', '48')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q297128'), ('label', 'David Henrie'), ('num_episode', '48')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q16149506'), ('label', 'Charlene Amoia'), ('num_episode', '17')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q199929'), ('label', 'Jennifer Morrison'), ('num_episode', '12')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q552889'), ('label', 'Marshall Manesh'), ('num_episode', '11')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q229728'), ('label', 'Sarah Chalke'), ('num_episode', '10')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q591238'), ('label', 'Bill Fagerbakke'), ('num_episode', '9')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q1396070'), ('label', 'Suzie Plakson'), ('num_episode', '9')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q435839'), ('label', 'Ashley Williams'), ('num_episode', '9')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q1189102'), ('label', 'Nazanin Boniadi'), ('num_episode', '8')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q888178'), ('label', 'Bob Odenkirk'), ('num_episode', '7')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q1139526'), ('label', 'Bryan Callen'), ('num_episode', '6')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q238425'), ('label', 'Cristine Rose'), ('num_episode', '5')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q984397'), ('label', 'David Burtka'), ('num_episode', '5')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q454698'), ('label', 'Darcy Rose Byrnes'), ('num_episode', '5')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q470005'), ('label', 'Joe Manganiello'), ('num_episode', '5')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q366322'), ('label', 'Alexis Denisof'), ('num_episode', '5')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q1255263'), ('label', 'Jason Jones'), ('num_episode', '4')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q2706805'), ('label', 'Taran Killam'), ('num_episode', '4')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q516659'), ('label', 'Virginia Williams'), ('num_episode', '4')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q220536'), ('label', 'Kal Penn'), ('num_episode', '4')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q3675563'), ('label', 'Chris Romano'), ('num_episode', '4')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q1397155'), ('label', 'Wayne Brady'), ('num_episode', '4')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q233882'), ('label', 'Frances Conroy'), ('num_episode', '3')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q277895'), ('label', 'Alan Thicke'), ('num_episode', '3')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q230176'), ('label', 'Danneel Ackles'), ('num_episode', '3')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q5186320'), ('label', 'Cristin Milioti'), ('num_episode', '3')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q271765'), ('label', 'Laura Bell Bundy'), ('num_episode', '3')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q207506'), ('label', 'Kyle MacLachlan'), ('num_episode', '3')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q377424'), ('label', 'Chris Elliott'), ('num_episode', '3')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q782662'), ('label', 'Michael Gross'), ('num_episode', '3')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q171567'), ('label', 'Laura Prepon'), ('num_episode', '3')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q264787'), ('label', 'April Bowlby'), ('num_episode', '3')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q926420'), ('label', 'Robbie Amell'), ('num_episode', '2')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q242949'), ('label', 'Danica McKellar'), ('num_episode', '2')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q329744'), ('label', 'Martin Short'), ('num_episode', '2')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q23547'), ('label', 'Bryan Cranston'), ('num_episode', '2')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q255293'), ('label', 'Geoff Stults'), ('num_episode', '2')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q220949'), ('label', 'Rachel Bilson'), ('num_episode', '2')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q1802786'), ('label', 'Matt L. Jones'), ('num_episode', '2')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q770841'), ('label', 'Ben Vereen'), ('num_episode', '2')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q265031'), ('label', 'Renée Taylor'), ('num_episode', '2')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q236918'), ('label', 'Anne Dudek'), ('num_episode', '2')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q311271'), ('label', 'John Lithgow'), ('num_episode', '2')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q566885'), ('label', 'Harry Groener'), ('num_episode', '2')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q11975'), ('label', 'Britney Spears'), ('num_episode', '2')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q279816'), ('label', 'Dawn Olivieri'), ('num_episode', '2')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q139611'), ('label', 'Zachary Gordon'), ('num_episode', '2')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q439070'), ('label', 'E. E. Bell'), ('num_episode', '2')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q530646'), ('label', 'Ray Wise'), ('num_episode', '2')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q1319744'), ('label', 'Will Forte'), ('num_episode', '2')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q3306283'), ('label', 'Dwight Hicks'), ('num_episode', '1')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q233042'), ('label', 'Nancy Travis'), ('num_episode', '1')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q741909'), ('label', 'Chris Kattan'), ('num_episode', '1')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q635974'), ('label', 'Michael Trucco'), ('num_episode', '1')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q229349'), ('label', 'Heather Morris'), ('num_episode', '1')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q1459918'), ('label', 'James Tupper'), ('num_episode', '1')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q2842824'), ('label', 'America Olivo'), ('num_episode', '1')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q3002075'), ('label', 'Craig Thomas'), ('num_episode', '1')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q463673'), ('label', 'Regis Philbin'), ('num_episode', '1')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q231744'), ('label', 'Kendra Wilkinson'), ('num_episode', '1')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q4172513'), ('label', 'Jessica Barth'), ('num_episode', '1')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q444146'), ('label', 'Amber Stevens'), ('num_episode', '1')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q289721'), ('label', 'Kimberly Matula'), ('num_episode', '1')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q522856'), ('label', 'Kate Micucci'), ('num_episode', '1')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q234715'), ('label', 'Jamie-Lynn Sigler'), ('num_episode', '1')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q3050431'), ('label', 'Meredith Scott Lynn'), ('num_episode', '1')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q3045427'), ('label', 'George Cheung'), ('num_episode', '1')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q231091'), ('label', 'Morena Baccarin'), ('num_episode', '1')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q235740'), ('label', 'Busy Philipps'), ('num_episode', '1')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q6491295'), ('label', 'Larry Wilmore'), ('num_episode', '1')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q27322'), ('label', 'Jason Lewis'), ('num_episode', '1')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q433355'), ('label', 'Patricia Belcher'), ('num_episode', '1')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q233433'), ('label', 'Rachelle Lefevre'), ('num_episode', '1')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q240720'), ('label', 'Deanna Russo'), ('num_episode', '1')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q2778807'), ('label', 'Michael Mantell'), ('num_episode', '1')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q433138'), ('label', 'Pat Crawford Brown'), ('num_episode', '1')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q5334589'), ('label', 'Ed Brigadier'), ('num_episode', '1')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q2507611'), ('label', 'Khary Payton'), ('num_episode', '1')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q2604240'), ('label', 'Collette Wolfe'), ('num_episode', '1')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q272927'), ('label', 'Kristen Schaal'), ('num_episode', '1')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q192165'), ('label', 'Danny Glover'), ('num_episode', '1')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q60036'), ('label', 'Heidi Klum'), ('num_episode', '1')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q270638'), ('label', 'Vanessa Lachey'), ('num_episode', '1')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q158250'), ('label', 'Peter Bogdanovich'), ('num_episode', '1')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q6701600'), ('label', 'Luka Jones'), ('num_episode', '1')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q614851'), ('label', 'Eric Braeden'), ('num_episode', '1')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q229669'), ('label', 'Malin Åkerman'), ('num_episode', '1')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q247064'), ('label', 'Bill Macy'), ('num_episode', '1')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q17428816'), ('label', 'Austin Majors'), ('num_episode', '1')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q3099305'), ('label', 'Gattlin Griffith'), ('num_episode', '1')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q458582'), ('label', 'Betsy Rue'), ('num_episode', '1')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q269891'), ('label', 'Julianna Guill'), ('num_episode', '1')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q446031'), ('label', 'Nikki Griffin'), ('num_episode', '1')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q446481'), ('label', 'Harvey Fierstein'), ('num_episode', '1')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q459839'), ('label', "Brooke D'Orsay"), ('num_episode', '1')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q49004'), ('label', 'Patrick Swayze'), ('num_episode', '1')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q4993338'), ('label', 'Ezra Buzzington'), ('num_episode', '1')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q347922'), ('label', 'Melissa Molinaro'), ('num_episode', '1')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q558412'), ('label', 'Rick Malambri'), ('num_episode', '1')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q2903362'), ('label', 'Bill Suplee'), ('num_episode', '1')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q40715'), ('label', 'Jennifer Lopez'), ('num_episode', '1')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q943613'), ('label', 'Samm Levine'), ('num_episode', '1')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q566037'), ('label', 'Scoot McNairy'), ('num_episode', '1')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q2844557'), ('label', 'Amy Gumenick'), ('num_episode', '1')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q44442'), ('label', 'Dan Castellaneta'), ('num_episode', '1')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q545172'), ('label', 'Matt Frewer'), ('num_episode', '1')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q978367'), ('label', 'Jesse Heiman'), ('num_episode', '1')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q123849'), ('label', 'Jane Seymour'), ('num_episode', '1')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q236189'), ('label', 'Judy Greer'), ('num_episode', '1')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q232927'), ('label', 'Jennifer Grey'), ('num_episode', '1')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q269137'), ('label', 'Sarah Wright'), ('num_episode', '1')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q761697'), ('label', 'Connie Sawyer'), ('num_episode', '1')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q8349'), ('label', '"Weird Al" Yankovic'), ('num_episode', '1')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q229940'), ('label', 'Lucy Hale'), ('num_episode', '1')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q23034377'), ('label', 'Lindsey Stoddart'), ('num_episode', '1')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q258237'), ('label', 'Beth Riesgraf'), ('num_episode', '1')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q238407'), ('label', 'Stacy Keibler'), ('num_episode', '1')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q3859348'), ('label', 'Misti Traya'), ('num_episode', '1')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q1332676'), ('label', 'William Schallert'), ('num_episode', '1')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q444480'), ('label', 'Elizabeth Bogush'), ('num_episode', '1')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q968718'), ('label', 'Bruce Gray'), ('num_episode', '1')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q238117'), ('label', 'Christina Pickles'), ('num_episode', '1')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q1280821'), ('label', 'Richard Gant'), ('num_episode', '1')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q321131'), ('label', 'Abigail Spencer'), ('num_episode', '1')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q535904'), ('label', 'Vanessa Lee Evigan'), ('num_episode', '1')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q3378803'), ('label', 'Phil Lord'), ('num_episode', '1')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q3109076'), ('label', 'Jay Acovone'), ('num_episode', '1')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q16729414'), ('label', 'Alec Gray'), ('num_episode', '1')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q2914539'), ('label', 'Jeff Probst'), ('num_episode', '1')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q512376'), ('label', 'Suzy Nakamura'), ('num_episode', '1')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q320973'), ('label', 'Robert Wisdom'), ('num_episode', '1')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q310322'), ('label', 'Will Sasso'), ('num_episode', '1')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q467496'), ('label', 'Marianne Muellerleile'), ('num_episode', '1')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q784009'), ('label', 'Danny Strong'), ('num_episode', '1')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q900740'), ('label', 'Raquel Alessi'), ('num_episode', '1')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q733691'), ('label', 'Brad Rowe'), ('num_episode', '1')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q5213110'), ('label', 'Dan Bakkedahl'), ('num_episode', '1')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q2633899'), ('label', 'Erin Cahill'), ('num_episode', '1')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q1189095'), ('label', 'Courtney Ford'), ('num_episode', '1')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q1806102'), ('label', 'Larry Poindexter'), ('num_episode', '1')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q312705'), ('label', 'John Cho'), ('num_episode', '1')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q289330'), ('label', 'Erin Cardillo'), ('num_episode', '1')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q260184'), ('label', 'Eva Amurri'), ('num_episode', '1')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q151866'), ('label', 'Adriana Lima'), ('num_episode', '1')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q3943077'), ('label', 'Ryan Michelle Bathe'), ('num_episode', '1')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q234137'), ('label', 'Megan Mullally'), ('num_episode', '1')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q152773'), ('label', 'Amy Acker'), ('num_episode', '1')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q348986'), ('label', 'Davis Cleveland'), ('num_episode', '1')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q2636696'), ('label', 'Alan Fudge'), ('num_episode', '1')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q298777'), ('label', 'Michael York'), ('num_episode', '1')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q3180253'), ('label', 'Joel McCrary'), ('num_episode', '1')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q6791001'), ('label', 'Matthew Moy'), ('num_episode', '1')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q236766'), ('label', 'Maggie Wheeler'), ('num_episode', '1')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q2942050'), ('label', 'Catherine Reitman'), ('num_episode', '1')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q438583'), ('label', 'Kevin Heffernan'), ('num_episode', '1')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q234353'), ('label', 'Lindsay Price'), ('num_episode', '1')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q131332'), ('label', 'Amanda Peet'), ('num_episode', '1')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q217160'), ('label', 'Kenny Rogers'), ('num_episode', '1')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q230821'), ('label', 'Marisa Miller'), ('num_episode', '1')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q2347123'), ('label', 'Steve Little'), ('num_episode', '1')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q1809038'), ('label', 'Caroline Lagerfelt'), ('num_episode', '1')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q1320939'), ('label', 'Tom Lenk'), ('num_episode', '1')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q465556'), ('label', 'Annie Ilonzeh'), ('num_episode', '1')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q215546'), ('label', 'Carrie Underwood'), ('num_episode', '1')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q450496'), ('label', 'Alyssa Shafer'), ('num_episode', '1')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q264914'), ('label', 'Jorge Garcia'), ('num_episode', '1')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q549562'), ('label', 'Ryan Pinkston'), ('num_episode', '1')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q187832'), ('label', 'Mandy Moore'), ('num_episode', '1')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q25176107'), ('label', 'Kevin Christy'), ('num_episode', '1')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q2656047'), ('label', 'Carter Bays'), ('num_episode', '1')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q5357354'), ('label', 'Todd Stashwick'), ('num_episode', '1')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q1402293'), ('label', 'Italia Ricci'), ('num_episode', '1')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q456258'), ('label', 'Charles Robinson'), ('num_episode', '1')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q1189470'), ('label', 'Jimmi Simpson'), ('num_episode', '1')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q291024'), ('label', 'Moon Zappa'), ('num_episode', '1')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q441451'), ('label', 'Rachele Brooke Smith'), ('num_episode', '1')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q231006'), ('label', 'Jayma Mays'), ('num_episode', '1')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q254775'), ('label', 'Brooke Nevin'), ('num_episode', '1')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q238029'), ('label', 'JoAnna García'), ('num_episode', '1')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q39574'), ('label', 'Candice King'), ('num_episode', '1')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q3052368'), ('label', 'Emily Baldoni'), ('num_episode', '1')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q471128'), ('label', 'Chi McBride'), ('num_episode', '1')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q667979'), ('label', 'Aaron Hill'), ('num_episode', '1')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q362616'), ('label', 'Jon Bernthal'), ('num_episode', '1')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q313392'), ('label', 'James Van Der Beek'), ('num_episode', '1')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q922264'), ('label', 'Eric Allan Kramer'), ('num_episode', '1')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q1159104'), ('label', 'Dan Lauria'), ('num_episode', '1')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q1532012'), ('label', 'Krista Kalmus'), ('num_episode', '1')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q16232252'), ('label', 'Kate Mansi'), ('num_episode', '1')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q488335'), ('label', 'Kevin Michael Richardson'), ('num_episode', '1')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q594265'), ('label', 'Neil Jackson'), ('num_episode', '1')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q531195'), ('label', 'Stephanie Faracy'), ('num_episode', '1')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q436881'), ('label', 'Kathleen Rose Perkins'), ('num_episode', '1')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q234514'), ('label', 'Camryn Manheim'), ('num_episode', '1')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q376031'), ('label', 'Gary Anthony Williams'), ('num_episode', '1')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q924222'), ('label', 'Diane Salinger'), ('num_episode', '1')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q2827976'), ('label', 'Ailsa Marshall'), ('num_episode', '1')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q311976'), ('label', 'Wayne Knight'), ('num_episode', '1')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q429619'), ('label', 'Valerie Azlynn'), ('num_episode', '1')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q17386547'), ('label', 'Peter Breitmayer'), ('num_episode', '1')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q448484'), ('label', 'Darby Stanchfield'), ('num_episode', '1')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q525572'), ('label', 'Erinn Bartlett'), ('num_episode', '1')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q469914'), ('label', 'Lindsay Sloane'), ('num_episode', '1')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q239223'), ('label', 'Kaylee DeFer'), ('num_episode', '1')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q3936377'), ('label', 'Nate Torrence'), ('num_episode', '1')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q290156'), ('label', 'Christine Woods'), ('num_episode', '1')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q261104'), ('label', 'Kelly Stables'), ('num_episode', '1')]
# 214

# %% [markdown]
# ## Task 4
# Check who is the actor who acted in more films while working on "How I met your mother" (the result set must be a list of triples actor/actress IRI, label and #films).

# %%
# write your queries
# getting whatever an arbitrary actor (Josh Radnor) has played in using the 'cast member' and also by the use of
# 'instance of' property we see whether it is a film or not
queryString = """
SELECT DISTINCT ?subject ?label ?object ?instance_of
WHERE
{
   # ?subject wdt:P161 wd:Q223455.
   # ?subject wdt:P31 ?object.
   
   # ?subject sc:name ?label.
   # ?object sc:name ?instance_of.
}
LIMIT 50
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('subject', 'http://www.wikidata.org/entity/Q4137975'), ('label', 'Liberal Arts'), ('object', 'http://www.wikidata.org/entity/Q11424'), ('instance_of', 'film')]
# [('subject', 'http://www.wikidata.org/entity/Q4690774'), ('label', 'Afternoon Delight'), ('object', 'http://www.wikidata.org/entity/Q11424'), ('instance_of', 'film')]
# [('subject', 'http://www.wikidata.org/entity/Q52715605'), ('label', 'Social Animals'), ('object', 'http://www.wikidata.org/entity/Q11424'), ('instance_of', 'film')]
# [('subject', 'http://www.wikidata.org/entity/Q18170028'), ('label', 'The Galapagos Affair'), ('object', 'http://www.wikidata.org/entity/Q11424'), ('instance_of', 'film')]
# [('subject', 'http://www.wikidata.org/entity/Q1050720'), ('label', 'Happythankyoumoreplease'), ('object', 'http://www.wikidata.org/entity/Q11424'), ('instance_of', 'film')]
# [('subject', 'http://www.wikidata.org/entity/Q1145848'), ('label', 'Not Another Teen Movie'), ('object', 'http://www.wikidata.org/entity/Q11424'), ('instance_of', 'film')]
# [('subject', 'http://www.wikidata.org/entity/Q2884686'), ('label', "Barney's Great Adventure"), ('object', 'http://www.wikidata.org/entity/Q11424'), ('instance_of', 'film')]
# [('subject', 'http://www.wikidata.org/entity/Q5264968'), ('label', 'Desperation Day'), ('object', 'http://www.wikidata.org/entity/Q21191270'), ('instance_of', 'television series episode')]
# [('subject', 'http://www.wikidata.org/entity/Q5521981'), ('label', 'Garbage Island'), ('object', 'http://www.wikidata.org/entity/Q21191270'), ('instance_of', 'television series episode')]
# [('subject', 'http://www.wikidata.org/entity/Q7080458'), ('label', 'Oh Honey'), ('object', 'http://www.wikidata.org/entity/Q21191270'), ('instance_of', 'television series episode')]
# [('subject', 'http://www.wikidata.org/entity/Q5888848'), ('label', 'Home Wreckers'), ('object', 'http://www.wikidata.org/entity/Q21191270'), ('instance_of', 'television series episode')]
# [('subject', 'http://www.wikidata.org/entity/Q7858076'), ('label', 'Twin Beds'), ('object', 'http://www.wikidata.org/entity/Q21191270'), ('instance_of', 'television series episode')]
# [('subject', 'http://www.wikidata.org/entity/Q8074081'), ('label', 'Zoo or False'), ('object', 'http://www.wikidata.org/entity/Q21191270'), ('instance_of', 'television series episode')]
# [('subject', 'http://www.wikidata.org/entity/Q4786988'), ('label', 'Architect of Destruction'), ('object', 'http://www.wikidata.org/entity/Q21191270'), ('instance_of', 'television series episode')]
# [('subject', 'http://www.wikidata.org/entity/Q4838409'), ('label', 'Baby Talk'), ('object', 'http://www.wikidata.org/entity/Q21191270'), ('instance_of', 'television series episode')]
# [('subject', 'http://www.wikidata.org/entity/Q7632493'), ('label', 'Subway Wars'), ('object', 'http://www.wikidata.org/entity/Q21191270'), ('instance_of', 'television series episode')]
# [('subject', 'http://www.wikidata.org/entity/Q11696021'), ('label', 'Nothing Good Happens After 2 A.M.'), ('object', 'http://www.wikidata.org/entity/Q21191270'), ('instance_of', 'television series episode')]
# [('subject', 'http://www.wikidata.org/entity/Q1327587'), ('label', 'Okay Awesome'), ('object', 'http://www.wikidata.org/entity/Q21191270'), ('instance_of', 'television series episode')]
# [('subject', 'http://www.wikidata.org/entity/Q3480575'), ('label', 'Return of the Shirt'), ('object', 'http://www.wikidata.org/entity/Q21191270'), ('instance_of', 'television series episode')]
# [('subject', 'http://www.wikidata.org/entity/Q467447'), ('label', 'Pilot'), ('object', 'http://www.wikidata.org/entity/Q21191270'), ('instance_of', 'television series episode')]
# [('subject', 'http://www.wikidata.org/entity/Q468587'), ('label', 'Purple Giraffe'), ('object', 'http://www.wikidata.org/entity/Q21191270'), ('instance_of', 'television series episode')]
# [('subject', 'http://www.wikidata.org/entity/Q471448'), ('label', 'Sweet Taste of Liberty'), ('object', 'http://www.wikidata.org/entity/Q21191270'), ('instance_of', 'television series episode')]
# [('subject', 'http://www.wikidata.org/entity/Q4809956'), ('label', 'Game Night'), ('object', 'http://www.wikidata.org/entity/Q21191270'), ('instance_of', 'television series episode')]
# [('subject', 'http://www.wikidata.org/entity/Q4817584'), ('label', 'Drumroll, Please'), ('object', 'http://www.wikidata.org/entity/Q21191270'), ('instance_of', 'television series episode')]
# [('subject', 'http://www.wikidata.org/entity/Q4818636'), ('label', 'Life Among the Gorillas'), ('object', 'http://www.wikidata.org/entity/Q21191270'), ('instance_of', 'television series episode')]
# [('subject', 'http://www.wikidata.org/entity/Q4818989'), ('label', 'Cupcake'), ('object', 'http://www.wikidata.org/entity/Q21191270'), ('instance_of', 'television series episode')]
# [('subject', 'http://www.wikidata.org/entity/Q4819005'), ('label', 'The Wedding'), ('object', 'http://www.wikidata.org/entity/Q21191270'), ('instance_of', 'television series episode')]
# [('subject', 'http://www.wikidata.org/entity/Q4884249'), ('label', 'Belly Full of Turkey'), ('object', 'http://www.wikidata.org/entity/Q21191270'), ('instance_of', 'television series episode')]
# [('subject', 'http://www.wikidata.org/entity/Q5151207'), ('label', 'Come On'), ('object', 'http://www.wikidata.org/entity/Q21191270'), ('instance_of', 'television series episode')]
# [('subject', 'http://www.wikidata.org/entity/Q6781049'), ('label', 'Mary the Paralegal'), ('object', 'http://www.wikidata.org/entity/Q21191270'), ('instance_of', 'television series episode')]
# [('subject', 'http://www.wikidata.org/entity/Q6857975'), ('label', 'Milk'), ('object', 'http://www.wikidata.org/entity/Q21191270'), ('instance_of', 'television series episode')]
# [('subject', 'http://www.wikidata.org/entity/Q7731151'), ('label', 'The Duel'), ('object', 'http://www.wikidata.org/entity/Q21191270'), ('instance_of', 'television series episode')]
# [('subject', 'http://www.wikidata.org/entity/Q7747382'), ('label', 'The Limo'), ('object', 'http://www.wikidata.org/entity/Q21191270'), ('instance_of', 'television series episode')]
# [('subject', 'http://www.wikidata.org/entity/Q7757165'), ('label', 'The Pineapple Incident'), ('object', 'http://www.wikidata.org/entity/Q21191270'), ('instance_of', 'television series episode')]
# [('subject', 'http://www.wikidata.org/entity/Q8072588'), ('label', 'Zip, Zip, Zip'), ('object', 'http://www.wikidata.org/entity/Q21191270'), ('instance_of', 'television series episode')]
# [('subject', 'http://www.wikidata.org/entity/Q8247171'), ('label', 'Best Prom Ever'), ('object', 'http://www.wikidata.org/entity/Q21191270'), ('instance_of', 'television series episode')]
# [('subject', 'http://www.wikidata.org/entity/Q9030442'), ('label', 'Matchmaker'), ('object', 'http://www.wikidata.org/entity/Q21191270'), ('instance_of', 'television series episode')]
# [('subject', 'http://www.wikidata.org/entity/Q9078314'), ('label', 'Slutty Pumpkin'), ('object', 'http://www.wikidata.org/entity/Q21191270'), ('instance_of', 'television series episode')]
# [('subject', 'http://www.wikidata.org/entity/Q7538737'), ('label', 'Slapsgiving'), ('object', 'http://www.wikidata.org/entity/Q21191270'), ('instance_of', 'television series episode')]
# [('subject', 'http://www.wikidata.org/entity/Q7538739'), ('label', 'Slapsgiving 2: Revenge of the Slap'), ('object', 'http://www.wikidata.org/entity/Q21191270'), ('instance_of', 'television series episode')]
# [('subject', 'http://www.wikidata.org/entity/Q7578829'), ('label', 'Spoiler Alert'), ('object', 'http://www.wikidata.org/entity/Q21191270'), ('instance_of', 'television series episode')]
# [('subject', 'http://www.wikidata.org/entity/Q7757442'), ('label', 'The Playbook'), ('object', 'http://www.wikidata.org/entity/Q21191270'), ('instance_of', 'television series episode')]
# [('subject', 'http://www.wikidata.org/entity/Q7775094'), ('label', 'The Window'), ('object', 'http://www.wikidata.org/entity/Q21191270'), ('instance_of', 'television series episode')]
# [('subject', 'http://www.wikidata.org/entity/Q7776702'), ('label', 'The Yips'), ('object', 'http://www.wikidata.org/entity/Q21191270'), ('instance_of', 'television series episode')]
# [('subject', 'http://www.wikidata.org/entity/Q5286037'), ('label', 'Do I Know You?'), ('object', 'http://www.wikidata.org/entity/Q21191270'), ('instance_of', 'television series episode')]
# [('subject', 'http://www.wikidata.org/entity/Q5977616'), ('label', 'I Heart NJ'), ('object', 'http://www.wikidata.org/entity/Q21191270'), ('instance_of', 'television series episode')]
# [('subject', 'http://www.wikidata.org/entity/Q7716685'), ('label', 'The Best Burger in New York'), ('object', 'http://www.wikidata.org/entity/Q21191270'), ('instance_of', 'television series episode')]
# [('subject', 'http://www.wikidata.org/entity/Q7428911'), ('label', 'Say Cheese'), ('object', 'http://www.wikidata.org/entity/Q21191270'), ('instance_of', 'television series episode')]
# [('subject', 'http://www.wikidata.org/entity/Q48986965'), ('label', 'Last Forever, Part I'), ('object', 'http://www.wikidata.org/entity/Q21191270'), ('instance_of', 'television series episode')]
# [('subject', 'http://www.wikidata.org/entity/Q48986998'), ('label', 'Last Forever, Part II'), ('object', 'http://www.wikidata.org/entity/Q21191270'), ('instance_of', 'television series episode')]
# 50

# %%
# getting only the films that an arbitrary actor (Josh Radnor) has played in
queryString = """
SELECT DISTINCT ?film ?label 
WHERE
{
   # ?film wdt:P161 wd:Q223455.
   # ?film wdt:P31 wd:Q11424.
   
   # ?film sc:name ?label.
}
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('film', 'http://www.wikidata.org/entity/Q4137975'), ('label', 'Liberal Arts')]
# [('film', 'http://www.wikidata.org/entity/Q4690774'), ('label', 'Afternoon Delight')]
# [('film', 'http://www.wikidata.org/entity/Q52715605'), ('label', 'Social Animals')]
# [('film', 'http://www.wikidata.org/entity/Q18170028'), ('label', 'The Galapagos Affair')]
# [('film', 'http://www.wikidata.org/entity/Q1050720'), ('label', 'Happythankyoumoreplease')]
# [('film', 'http://www.wikidata.org/entity/Q1145848'), ('label', 'Not Another Teen Movie')]
# [('film', 'http://www.wikidata.org/entity/Q2884686'), ('label', "Barney's Great Adventure")]
# 7

# %%
# getting object/data properties of an arbitrary film (Liberal Arts)
queryString = """
SELECT DISTINCT ?property ?label
WHERE
{
   wd:Q4137975 ?property ?object.
   
   # ?property sc:name ?label.
}
LIMIT 50
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('property', 'http://www.wikidata.org/prop/direct/P1040'), ('label', 'film editor')]
# [('property', 'http://www.wikidata.org/prop/direct/P1237'), ('label', 'Box Office Mojo film ID (former scheme)')]
# [('property', 'http://www.wikidata.org/prop/direct/P1258'), ('label', 'Rotten Tomatoes ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1265'), ('label', 'AlloCiné film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P136'), ('label', 'genre')]
# [('property', 'http://www.wikidata.org/prop/direct/P1476'), ('label', 'title')]
# [('property', 'http://www.wikidata.org/prop/direct/P1562'), ('label', 'AllMovie title ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P161'), ('label', 'cast member')]
# [('property', 'http://www.wikidata.org/prop/direct/P1712'), ('label', 'Metacritic ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1874'), ('label', 'Netflix ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1970'), ('label', 'MovieMeter film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2047'), ('label', 'duration')]
# [('property', 'http://www.wikidata.org/prop/direct/P2518'), ('label', 'Scope.dk film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2529'), ('label', 'ČSFD film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2603'), ('label', 'Kinopoisk film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P272'), ('label', 'production company')]
# [('property', 'http://www.wikidata.org/prop/direct/P31'), ('label', 'instance of')]
# [('property', 'http://www.wikidata.org/prop/direct/P3107'), ('label', 'LdiF ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3129'), ('label', 'cine.gr film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3135'), ('label', 'elCinema film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3138'), ('label', 'OFDb film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3143'), ('label', 'elFilm film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P345'), ('label', 'IMDb ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P364'), ('label', 'original language of film or TV show')]
# [('property', 'http://www.wikidata.org/prop/direct/P3844'), ('label', 'Deutsche Synchronkartei film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3933'), ('label', 'Cinema.de ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P437'), ('label', 'distribution format')]
# [('property', 'http://www.wikidata.org/prop/direct/P4529'), ('label', 'Douban film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P462'), ('label', 'color')]
# [('property', 'http://www.wikidata.org/prop/direct/P4632'), ('label', 'Bechdel Test Movie List ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P480'), ('label', 'FilmAffinity ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4947'), ('label', 'TMDb movie ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P495'), ('label', 'country of origin')]
# [('property', 'http://www.wikidata.org/prop/direct/P5021'), ('label', 'assessment')]
# [('property', 'http://www.wikidata.org/prop/direct/P5032'), ('label', 'Filmweb.pl film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P57'), ('label', 'director')]
# [('property', 'http://www.wikidata.org/prop/direct/P577'), ('label', 'publication date')]
# [('property', 'http://www.wikidata.org/prop/direct/P5786'), ('label', 'Moviepilot.de film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P58'), ('label', 'screenwriter')]
# [('property', 'http://www.wikidata.org/prop/direct/P6127'), ('label', 'Letterboxd film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6398'), ('label', 'iTunes movie ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P646'), ('label', 'Freebase ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6562'), ('label', 'Google Play Movies & TV ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P750'), ('label', 'distributed by')]
# [('property', 'http://www.wikidata.org/prop/direct/P840'), ('label', 'narrative location')]
# [('property', 'http://www.wikidata.org/prop/direct/P905'), ('label', 'PORT film ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P915'), ('label', 'filming location')]
# [('property', 'http://www.wikidata.org/prop/direct/P9586'), ('label', 'Apple TV movie ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2826'), ('label', 'Megogo ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6466'), ('label', 'Hulu movie ID')]
# 50

# %%
# checking the 'publication date' property of the films that an arbitrary actor (Josh Radnor) has played in
queryString = """
SELECT ?film ?label ?publication_date
WHERE
{
   # ?film wdt:P161 wd:Q223455.
   # ?film wdt:P31 wd:Q11424.
   # ?film wdt:P577 ?publication_date.
   
   # ?film sc:name ?label.
}
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('film', 'http://www.wikidata.org/entity/Q4137975'), ('label', 'Liberal Arts'), ('publication_date', '2012-01-01T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q4690774'), ('label', 'Afternoon Delight'), ('publication_date', '2013-01-21T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q4690774'), ('label', 'Afternoon Delight'), ('publication_date', '2015-05-07T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q52715605'), ('label', 'Social Animals'), ('publication_date', '2018-06-01T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q18170028'), ('label', 'The Galapagos Affair'), ('publication_date', '2013-01-01T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q1050720'), ('label', 'Happythankyoumoreplease'), ('publication_date', '2010-01-01T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q1145848'), ('label', 'Not Another Teen Movie'), ('publication_date', '2001-12-07T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q1145848'), ('label', 'Not Another Teen Movie'), ('publication_date', '2001-12-14T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q1145848'), ('label', 'Not Another Teen Movie'), ('publication_date', '2002-03-08T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q1145848'), ('label', 'Not Another Teen Movie'), ('publication_date', '2002-04-04T00:00:00Z')]
# [('film', 'http://www.wikidata.org/entity/Q2884686'), ('label', "Barney's Great Adventure"), ('publication_date', '1998-01-01T00:00:00Z')]
# 11

# %%
# getting the 'start time' and 'end time' properties of node 'HIMYM'
queryString = """
SELECT ?label ?start_time ?end_time
WHERE
{
   wd:Q147235 wdt:P580 ?start_time.
   wd:Q147235 wdt:P582 ?end_time.

   wd:Q147235 sc:name ?label
}
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('label', 'How I Met Your Mother'), ('start_time', '2005-09-19T00:00:00Z'), ('end_time', '2014-03-31T00:00:00Z')]
# 1

# %%
# getting only the films that an arbitrary actor (Josh Radnor) has played in, 
# that were published between the start and end time of 'HIMYM'
queryString = """
SELECT DISTINCT ?film ?label 
WHERE
{
   # ?film wdt:P161 wd:Q223455.
   # ?film wdt:P31 wd:Q11424.
   # ?film wdt:P577 ?publication_date.
   
   FILTER("2005-09-19T00:00:00Z"^^xsd:dateTime <= ?publication_date && ?publication_date <= "2014-03-31T00:00:00Z"^^xsd:dateTime)
   
   # ?film sc:name ?label.
}
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('film', 'http://www.wikidata.org/entity/Q4137975'), ('label', 'Liberal Arts')]
# [('film', 'http://www.wikidata.org/entity/Q4690774'), ('label', 'Afternoon Delight')]
# [('film', 'http://www.wikidata.org/entity/Q18170028'), ('label', 'The Galapagos Affair')]
# [('film', 'http://www.wikidata.org/entity/Q1050720'), ('label', 'Happythankyoumoreplease')]
# 4

# %% [markdown]
# Final query for this task

# %%
# write your final query
queryString = """
SELECT DISTINCT ?actor_iri ?label (COUNT(?film) AS ?num_film)
WHERE
{
   wd:Q147235 wdt:P161 ?actor_iri.
   # ?film wdt:P161 ?actor_iri.
   # ?film wdt:P31 wd:Q11424.
   # ?film wdt:P577 ?publication_date.
   
   FILTER("2005-09-19T00:00:00Z"^^xsd:dateTime <= ?publication_date && ?publication_date <= "2014-03-31T00:00:00Z"^^xsd:dateTime)
   
   # ?actor_iri sc:name ?label.
}
GROUP BY ?actor_iri ?label
ORDER BY DESC(?num_film)
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('actor_iri', 'http://www.wikidata.org/entity/Q192165'), ('label', 'Danny Glover'), ('num_film', '60')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q255293'), ('label', 'Geoff Stults'), ('num_film', '39')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q1319539'), ('label', 'Thomas Lennon'), ('num_film', '36')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q229669'), ('label', 'Malin Åkerman'), ('num_film', '35')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q236189'), ('label', 'Judy Greer'), ('num_film', '33')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q1319744'), ('label', 'Will Forte'), ('num_film', '32')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q23547'), ('label', 'Bryan Cranston'), ('num_film', '30')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q312705'), ('label', 'John Cho'), ('num_film', '30')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q1189470'), ('label', 'Jimmi Simpson'), ('num_film', '30')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q566037'), ('label', 'Scoot McNairy'), ('num_film', '28')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q716936'), ('label', 'Joe Lo Truglio'), ('num_film', '28')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q272927'), ('label', 'Kristen Schaal'), ('num_film', '27')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q202304'), ('label', 'Jason Segel'), ('num_film', '27')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q131332'), ('label', 'Amanda Peet'), ('num_film', '25')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q469579'), ('label', 'Mircea Monroe'), ('num_film', '24')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q634684'), ('label', 'Roger Bart'), ('num_film', '24')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q311271'), ('label', 'John Lithgow'), ('num_film', '23')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q362616'), ('label', 'Jon Bernthal'), ('num_film', '23')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q530646'), ('label', 'Ray Wise'), ('num_film', '22')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q591238'), ('label', 'Bill Fagerbakke'), ('num_film', '21')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q4993338'), ('label', 'Ezra Buzzington'), ('num_film', '21')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q607793'), ('label', 'Dave Foley'), ('num_film', '21')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q485310'), ('label', 'Neil Patrick Harris'), ('num_film', '21')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q139611'), ('label', 'Zachary Gordon'), ('num_film', '20')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q199929'), ('label', 'Jennifer Morrison'), ('num_film', '19')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q79031'), ('label', 'Mike Tyson'), ('num_film', '18')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q1139526'), ('label', 'Bryan Callen'), ('num_film', '18')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q469914'), ('label', 'Lindsay Sloane'), ('num_film', '18')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q392370'), ('label', 'Jon Heder'), ('num_film', '17')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q536437'), ('label', 'Edward Herrmann'), ('num_film', '17')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q200566'), ('label', 'Cobie Smulders'), ('num_film', '17')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q220536'), ('label', 'Kal Penn'), ('num_film', '17')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q2604240'), ('label', 'Collette Wolfe'), ('num_film', '16')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q40715'), ('label', 'Jennifer Lopez'), ('num_film', '16')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q466016'), ('label', 'Casey Wilson'), ('num_film', '16')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q2827706'), ('label', "Ahna O'Reilly"), ('num_film', '16')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q6382703'), ('label', 'Keegan-Michael Key'), ('num_film', '15')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q320973'), ('label', 'Robert Wisdom'), ('num_film', '15')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q3936377'), ('label', 'Nate Torrence'), ('num_film', '15')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q488335'), ('label', 'Kevin Michael Richardson'), ('num_film', '15')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q270260'), ('label', 'Chelan Simmons'), ('num_film', '15')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q2842824'), ('label', 'America Olivo'), ('num_film', '14')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q233882'), ('label', 'Frances Conroy'), ('num_film', '14')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q321131'), ('label', 'Abigail Spencer'), ('num_film', '14')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q230176'), ('label', 'Danneel Ackles'), ('num_film', '14')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q309900'), ('label', 'Peter Gallagher'), ('num_film', '14')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q2040329'), ('label', 'Hayes MacArthur'), ('num_film', '14')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q234137'), ('label', 'Megan Mullally'), ('num_film', '14')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q552889'), ('label', 'Marshall Manesh'), ('num_film', '14')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q888178'), ('label', 'Bob Odenkirk'), ('num_film', '14')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q1806933'), ('label', 'Rhys Darby'), ('num_film', '13')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q2943801'), ('label', 'Cedric Yarbrough'), ('num_film', '13')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q158250'), ('label', 'Peter Bogdanovich'), ('num_film', '13')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q269891'), ('label', 'Julianna Guill'), ('num_film', '13')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q943613'), ('label', 'Samm Levine'), ('num_film', '13')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q2706805'), ('label', 'Taran Killam'), ('num_film', '13')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q1374532'), ('label', 'Melissa Ordway'), ('num_film', '13')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q1320939'), ('label', 'Tom Lenk'), ('num_film', '13')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q1485367'), ('label', 'Bar Paly'), ('num_film', '13')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q3099305'), ('label', 'Gattlin Griffith'), ('num_film', '12')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q220949'), ('label', 'Rachel Bilson'), ('num_film', '12')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q471018'), ('label', 'Ernie Hudson'), ('num_film', '12')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q1255263'), ('label', 'Jason Jones'), ('num_film', '12')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q229914'), ('label', 'Lyndsy Fonseca'), ('num_film', '12')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q4964124'), ('label', 'Brian Huskey'), ('num_film', '12')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q186757'), ('label', 'Seth Green'), ('num_film', '12')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q123849'), ('label', 'Jane Seymour'), ('num_film', '11')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q269137'), ('label', 'Sarah Wright'), ('num_film', '11')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q310322'), ('label', 'Will Sasso'), ('num_film', '11')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q470005'), ('label', 'Joe Manganiello'), ('num_film', '11')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q486740'), ('label', "Conan O'Brien"), ('num_film', '11')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q187832'), ('label', 'Mandy Moore'), ('num_film', '11')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q231006'), ('label', 'Jayma Mays'), ('num_film', '11')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q522856'), ('label', 'Kate Micucci'), ('num_film', '10')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q235740'), ('label', 'Busy Philipps'), ('num_film', '10')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q27322'), ('label', 'Jason Lewis'), ('num_film', '10')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q174346'), ('label', 'Katie Holmes'), ('num_film', '10')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q545172'), ('label', 'Matt Frewer'), ('num_film', '10')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q467496'), ('label', 'Marianne Muellerleile'), ('num_film', '10')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q2347123'), ('label', 'Steve Little'), ('num_film', '10')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q2942050'), ('label', 'Catherine Reitman'), ('num_film', '10')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q500990'), ('label', 'Chase Ellison'), ('num_film', '10')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q471128'), ('label', 'Chi McBride'), ('num_film', '10')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q313392'), ('label', 'James Van Der Beek'), ('num_film', '10')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q1992967'), ('label', 'John Getz'), ('num_film', '10')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q531195'), ('label', 'Stephanie Faracy'), ('num_film', '10')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q429619'), ('label', 'Valerie Azlynn'), ('num_film', '10')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q741909'), ('label', 'Chris Kattan'), ('num_film', '9')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q1459918'), ('label', 'James Tupper'), ('num_film', '9')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q458582'), ('label', 'Betsy Rue'), ('num_film', '9')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q277895'), ('label', 'Alan Thicke'), ('num_film', '9')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q268549'), ('label', 'Sherri Shepherd'), ('num_film', '9')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q512376'), ('label', 'Suzy Nakamura'), ('num_film', '9')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q1189102'), ('label', 'Nazanin Boniadi'), ('num_film', '9')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q298777'), ('label', 'Michael York'), ('num_film', '9')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q3180253'), ('label', 'Joel McCrary'), ('num_film', '9')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q438583'), ('label', 'Kevin Heffernan'), ('num_film', '9')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q594265'), ('label', 'Neil Jackson'), ('num_film', '9')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q234514'), ('label', 'Camryn Manheim'), ('num_film', '9')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q444146'), ('label', 'Amber Stevens'), ('num_film', '8')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q234715'), ('label', 'Jamie-Lynn Sigler'), ('num_film', '8')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q3045427'), ('label', 'George Cheung'), ('num_film', '8')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q329744'), ('label', 'Martin Short'), ('num_film', '8')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q44442'), ('label', 'Dan Castellaneta'), ('num_film', '8')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q5213110'), ('label', 'Dan Bakkedahl'), ('num_film', '8')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q2633899'), ('label', 'Erin Cahill'), ('num_film', '8')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q607'), ('label', 'Michael Bloomberg'), ('num_film', '8')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q199927'), ('label', 'Alyson Hannigan'), ('num_film', '8')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q1809038'), ('label', 'Caroline Lagerfelt'), ('num_film', '8')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q551859'), ('label', 'Dimitri Diatchenko'), ('num_film', '8')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q4172513'), ('label', 'Jessica Barth'), ('num_film', '7')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q229349'), ('label', 'Heather Morris'), ('num_film', '7')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q4491707'), ('label', 'Olga Fonda'), ('num_film', '7')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q1150316'), ('label', 'Anna Camp'), ('num_film', '7')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q6184114'), ('label', 'Jerry Minor'), ('num_film', '7')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q435839'), ('label', 'Ashley Williams'), ('num_film', '7')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q16149506'), ('label', 'Charlene Amoia'), ('num_film', '7')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q207506'), ('label', 'Kyle MacLachlan'), ('num_film', '7')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q11975'), ('label', 'Britney Spears'), ('num_film', '7')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q254775'), ('label', 'Brooke Nevin'), ('num_film', '7')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q377424'), ('label', 'Chris Elliott'), ('num_film', '7')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q1976946'), ('label', 'Rachel Specter'), ('num_film', '7')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q436881'), ('label', 'Kathleen Rose Perkins'), ('num_film', '7')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q337557'), ('label', 'J. P. Manoux'), ('num_film', '6')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q231091'), ('label', 'Morena Baccarin'), ('num_film', '6')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q433138'), ('label', 'Pat Crawford Brown'), ('num_film', '6')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q6701600'), ('label', 'Luka Jones'), ('num_film', '6')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q347922'), ('label', 'Melissa Molinaro'), ('num_film', '6')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q229940'), ('label', 'Lucy Hale'), ('num_film', '6')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q770841'), ('label', 'Ben Vereen'), ('num_film', '6')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q5186320'), ('label', 'Cristin Milioti'), ('num_film', '6')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q260184'), ('label', 'Eva Amurri'), ('num_film', '6')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q152773'), ('label', 'Amy Acker'), ('num_film', '6')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q265031'), ('label', 'Renée Taylor'), ('num_film', '6')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q7340225'), ('label', 'Rob Huebel'), ('num_film', '6')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q5357354'), ('label', 'Todd Stashwick'), ('num_film', '6')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q1159104'), ('label', 'Dan Lauria'), ('num_film', '6')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q39574'), ('label', 'Candice King'), ('num_film', '6')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q366322'), ('label', 'Alexis Denisof'), ('num_film', '6')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q259697'), ('label', 'Camille Guaty'), ('num_film', '6')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q926420'), ('label', 'Robbie Amell'), ('num_film', '5')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q6491295'), ('label', 'Larry Wilmore'), ('num_film', '5')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q433355'), ('label', 'Patricia Belcher'), ('num_film', '5')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q6377325'), ('label', 'Kathy Uyen'), ('num_film', '5')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q60036'), ('label', 'Heidi Klum'), ('num_film', '5')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q558412'), ('label', 'Rick Malambri'), ('num_film', '5')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q446031'), ('label', 'Nikki Griffin'), ('num_film', '5')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q15720515'), ('label', 'George Finn'), ('num_film', '5')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q784009'), ('label', 'Danny Strong'), ('num_film', '5')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q549562'), ('label', 'Ryan Pinkston'), ('num_film', '5')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q279816'), ('label', 'Dawn Olivieri'), ('num_film', '5')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q238029'), ('label', 'JoAnna García'), ('num_film', '5')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q667979'), ('label', 'Aaron Hill'), ('num_film', '5')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q2708237'), ('label', 'Abby Elliott'), ('num_film', '5')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q261104'), ('label', 'Kelly Stables'), ('num_film', '5')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q171567'), ('label', 'Laura Prepon'), ('num_film', '5')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q376031'), ('label', 'Gary Anthony Williams'), ('num_film', '5')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q231744'), ('label', 'Kendra Wilkinson'), ('num_film', '4')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q73346'), ('label', 'Ralph Macchio'), ('num_film', '4')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q463673'), ('label', 'Regis Philbin'), ('num_film', '4')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q5334589'), ('label', 'Ed Brigadier'), ('num_film', '4')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q3303794'), ('label', 'Meagen Fay'), ('num_film', '4')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q223455'), ('label', 'Josh Radnor'), ('num_film', '4')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q230609'), ('label', 'Ashley Benson'), ('num_film', '4')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q1189095'), ('label', 'Courtney Ford'), ('num_film', '4')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q900740'), ('label', 'Raquel Alessi'), ('num_film', '4')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q733691'), ('label', 'Brad Rowe'), ('num_film', '4')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q966693'), ('label', 'William Zabka'), ('num_film', '4')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q186304'), ('label', 'Kim Kardashian'), ('num_film', '4')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q233042'), ('label', 'Nancy Travis'), ('num_film', '3')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q651231'), ('label', 'Boyz II Men'), ('num_film', '3')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q6276391'), ('label', 'Jordan Black'), ('num_film', '3')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q238425'), ('label', 'Cristine Rose'), ('num_film', '3')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q270638'), ('label', 'Vanessa Lachey'), ('num_film', '3')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q4078026'), ('label', 'Lance Barber'), ('num_film', '3')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q42493'), ('label', 'Katy Perry'), ('num_film', '3')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q8349'), ('label', '"Weird Al" Yankovic'), ('num_film', '3')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q297128'), ('label', 'David Henrie'), ('num_film', '3')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q1802786'), ('label', 'Matt L. Jones'), ('num_film', '3')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q2426173'), ('label', 'Vicki Lewis'), ('num_film', '3')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q4355895'), ('label', 'Preston Bailey'), ('num_film', '3')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q3943077'), ('label', 'Ryan Michelle Bathe'), ('num_film', '3')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q15978301'), ('label', 'Robert Belushi'), ('num_film', '3')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q271765'), ('label', 'Laura Bell Bundy'), ('num_film', '3')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q236918'), ('label', 'Anne Dudek'), ('num_film', '3')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q465556'), ('label', 'Annie Ilonzeh'), ('num_film', '3')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q264914'), ('label', 'Jorge Garcia'), ('num_film', '3')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q5057866'), ('label', 'Celeste Thorson'), ('num_film', '3')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q167696'), ('label', 'Nicole Scherzinger'), ('num_film', '3')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q3815315'), ('label', 'Kim Shaw'), ('num_film', '3')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q560516'), ('label', 'Andrew Rannells'), ('num_film', '3')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q2827976'), ('label', 'Ailsa Marshall'), ('num_film', '3')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q1397155'), ('label', 'Wayne Brady'), ('num_film', '3')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q234152'), ('label', 'Becki Newton'), ('num_film', '2')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q635974'), ('label', 'Michael Trucco'), ('num_film', '2')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q5212833'), ('label', 'Damon Gameau'), ('num_film', '2')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q242949'), ('label', 'Danica McKellar'), ('num_film', '2')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q2507611'), ('label', 'Khary Payton'), ('num_film', '2')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q874899'), ('label', 'Michele Boyd'), ('num_film', '2')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q446481'), ('label', 'Harvey Fierstein'), ('num_film', '2')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q238407'), ('label', 'Stacy Keibler'), ('num_film', '2')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q234636'), ('label', 'Heidi Montag'), ('num_film', '2')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q3109076'), ('label', 'Jay Acovone'), ('num_film', '2')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q6420832'), ('label', 'Michael Gladis'), ('num_film', '2')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q1392126'), ('label', 'Charles Chun'), ('num_film', '2')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q238117'), ('label', 'Christina Pickles'), ('num_film', '2')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q6151232'), ('label', 'Jane Carr'), ('num_film', '2')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q372613'), ('label', 'Phill Lewis'), ('num_film', '2')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q6386241'), ('label', 'Kelly Perine'), ('num_film', '2')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q454698'), ('label', 'Darcy Rose Byrnes'), ('num_film', '2')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q6791001'), ('label', 'Matthew Moy'), ('num_film', '2')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q18049086'), ('label', 'Danièle Watts'), ('num_film', '2')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q516659'), ('label', 'Virginia Williams'), ('num_film', '2')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q229728'), ('label', 'Sarah Chalke'), ('num_film', '2')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q320895'), ('label', 'Geddy Lee'), ('num_film', '2')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q3194153'), ('label', 'Katie Gill'), ('num_film', '2')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q1638889'), ('label', 'Rebecca Creskoff'), ('num_film', '2')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q4476096'), ('label', 'Katie Walder'), ('num_film', '2')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q6147046'), ('label', 'Jamie Kaler'), ('num_film', '2')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q215546'), ('label', 'Carrie Underwood'), ('num_film', '2')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q311769'), ('label', 'Jason Priestley'), ('num_film', '2')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q5108221'), ('label', 'Chris Tallman'), ('num_film', '2')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q291024'), ('label', 'Moon Zappa'), ('num_film', '2')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q741473'), ('label', 'Dennis Haskins'), ('num_film', '2')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q782662'), ('label', 'Michael Gross'), ('num_film', '2')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q922264'), ('label', 'Eric Allan Kramer'), ('num_film', '2')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q6788347'), ('label', 'Matt Besser'), ('num_film', '2')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q290156'), ('label', 'Christine Woods'), ('num_film', '2')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q2079473'), ('label', 'Greg Collins'), ('num_film', '2')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q439070'), ('label', 'E. E. Bell'), ('num_film', '2')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q16089775'), ('label', 'Barbara Perry'), ('num_film', '2')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q264787'), ('label', 'April Bowlby'), ('num_film', '2')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q230454'), ('label', 'k.d. lang'), ('num_film', '2')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q448484'), ('label', 'Darby Stanchfield'), ('num_film', '2')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q525572'), ('label', 'Erinn Bartlett'), ('num_film', '2')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q239223'), ('label', 'Kaylee DeFer'), ('num_film', '2')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q16199509'), ('label', 'Rachel Bloom'), ('num_film', '1')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q16335035'), ('label', 'Lindsey Morgan'), ('num_film', '1')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q778353'), ('label', 'Ryan Sypek'), ('num_film', '1')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q3306283'), ('label', 'Dwight Hicks'), ('num_film', '1')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q233397'), ('label', 'Arianna Huffington'), ('num_film', '1')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q3720665'), ('label', 'Eileen April Boylan'), ('num_film', '1')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q3050431'), ('label', 'Meredith Scott Lynn'), ('num_film', '1')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q240720'), ('label', 'Deanna Russo'), ('num_film', '1')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q614851'), ('label', 'Eric Braeden'), ('num_film', '1')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q3496382'), ('label', 'Jai Rodriguez'), ('num_film', '1')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q459839'), ('label', "Brooke D'Orsay"), ('num_film', '1')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q12524541'), ('label', 'Will Shadley'), ('num_film', '1')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q6207163'), ('label', 'Jocelyn Osorio'), ('num_film', '1')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q2844557'), ('label', 'Amy Gumenick'), ('num_film', '1')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q5300294'), ('label', 'Doug Benson'), ('num_film', '1')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q6276792'), ('label', 'Jordan Masterson'), ('num_film', '1')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q444480'), ('label', 'Elizabeth Bogush'), ('num_film', '1')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q130549'), ('label', 'Tracey Ullman'), ('num_film', '1')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q984397'), ('label', 'David Burtka'), ('num_film', '1')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q535904'), ('label', 'Vanessa Lee Evigan'), ('num_film', '1')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q1120700'), ('label', 'Orson Bean'), ('num_film', '1')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q1806102'), ('label', 'Larry Poindexter'), ('num_film', '1')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q4888924'), ('label', 'Benjamin Koldyke'), ('num_film', '1')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q289330'), ('label', 'Erin Cardillo'), ('num_film', '1')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q7339134'), ('label', 'Rizwan Manji'), ('num_film', '1')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q8979854'), ('label', 'Candace Kroslak'), ('num_film', '1')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q234353'), ('label', 'Lindsay Price'), ('num_film', '1')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q217160'), ('label', 'Kenny Rogers'), ('num_film', '1')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q450496'), ('label', 'Alyssa Shafer'), ('num_film', '1')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q6163370'), ('label', 'Jason Rogel'), ('num_film', '1')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q233886'), ('label', 'Tiffany'), ('num_film', '1')]
# [('actor_iri', 'http://www.wikidata.org/entity/Q1646482'), ('label', 'Lin-Manuel Miranda'), ('num_film', '1')]
# 268

# %% [markdown]
# ## Task 5
# Compare HIMYM with the tv series "The Office (US)" in terms of number of seasons, episods and cast members (the result set must be two elements -one for each tv series- of tv series IRI, label, #seasons, #episodes and #cast members).

# %%
# write your queries
# getting number of seasons and episodes of node 'HIMYM'
queryString = """
SELECT wd:Q147235 ?label ?num_season ?num_episode
WHERE
{
   wd:Q147235 wdt:P2437 ?num_season.
   wd:Q147235 wdt:P1113 ?num_episode.
   
   wd:Q147235 sc:name ?label.
}
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('callret-0', 'http://www.wikidata.org/entity/Q147235'), ('label', 'How I Met Your Mother'), ('num_season', '9'), ('num_episode', '208')]
# 1

# %%
# getting only number of cast members of node 'HIMYM'
queryString = """
SELECT wd:Q147235 ?label (COUNT (?cast_member) AS ?num_cast)
WHERE
{
   wd:Q147235 wdt:P161 ?cast_member.
   
   wd:Q147235 sc:name ?label.
}
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('callret-0', 'http://www.wikidata.org/entity/Q147235'), ('label', 'How I Met Your Mother'), ('num_cast', '480')]
# 1

# %% [markdown]
# Final query for this task

# %%
# write your final query
queryString = """
SELECT ?series_iri ?label ?num_season ?num_episode (COUNT (?cast_member) AS ?num_cast)
WHERE
{
   values ?series_iri { wd:Q147235 wd:Q23831 }
   
   # ?series_iri wdt:P2437 ?num_season.
   # ?series_iri wdt:P1113 ?num_episode.
   # ?series_iri wdt:P161 ?cast_member.
   
   # ?series_iri sc:name ?label.
}
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('series_iri', 'http://www.wikidata.org/entity/Q147235'), ('label', 'How I Met Your Mother'), ('num_season', '9'), ('num_episode', '208'), ('num_cast', '480')]
# [('series_iri', 'http://www.wikidata.org/entity/Q23831'), ('label', 'The Office'), ('num_season', '9'), ('num_episode', '201'), ('num_cast', '25')]
# 2

# %% [markdown]
# ## Task 6
# Return how many of the actors who are members of the cast of the tv series have [Kavin Bacon number](https://en.wikipedia.org/wiki/Six_Degrees_of_Kevin_Bacon#:~:text=Kevin%20Bacon%20himself%20has%20a,Bacon%20number%20is%20N%2B1.) equal to 2 (the result set must be a list of couples actor/actress IRI and label).

# %%
# write your queries
# getting object/data properties of an arbitrary actress (Annie Ilonzeh) that found previously
queryString = """
SELECT DISTINCT ?property ?label
WHERE
{
   wd:Q465556 ?property ?object.
   
   # ?property sc:name ?label.
}
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('property', 'http://www.wikidata.org/prop/direct/P106'), ('label', 'occupation')]
# [('property', 'http://www.wikidata.org/prop/direct/P1266'), ('label', 'AlloCiné person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P172'), ('label', 'ethnic group')]
# [('property', 'http://www.wikidata.org/prop/direct/P19'), ('label', 'place of birth')]
# [('property', 'http://www.wikidata.org/prop/direct/P2002'), ('label', 'Twitter username')]
# [('property', 'http://www.wikidata.org/prop/direct/P2003'), ('label', 'Instagram username')]
# [('property', 'http://www.wikidata.org/prop/direct/P2013'), ('label', 'Facebook ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2019'), ('label', 'AllMovie person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2031'), ('label', 'work period (start)')]
# [('property', 'http://www.wikidata.org/prop/direct/P21'), ('label', 'sex or gender')]
# [('property', 'http://www.wikidata.org/prop/direct/P214'), ('label', 'VIAF ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P227'), ('label', 'GND ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2435'), ('label', 'PORT person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2604'), ('label', 'Kinopoisk person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2605'), ('label', 'ČSFD person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P27'), ('label', 'country of citizenship')]
# [('property', 'http://www.wikidata.org/prop/direct/P31'), ('label', 'instance of')]
# [('property', 'http://www.wikidata.org/prop/direct/P3142'), ('label', 'EDb person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P345'), ('label', 'IMDb ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4332'), ('label', 'Deutsche Synchronkartei actor ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4657'), ('label', 'The Numbers person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4666'), ('label', 'CineMagia person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4985'), ('label', 'TMDb person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5008'), ('label', 'on focus list of Wikimedia project')]
# [('property', 'http://www.wikidata.org/prop/direct/P5284'), ('label', 'Douban movie celebrity ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P569'), ('label', 'date of birth')]
# [('property', 'http://www.wikidata.org/prop/direct/P646'), ('label', 'Freebase ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P69'), ('label', 'educated at')]
# [('property', 'http://www.wikidata.org/prop/direct/P735'), ('label', 'given name')]
# [('property', 'http://www.wikidata.org/prop/direct/P7859'), ('label', 'WorldCat Identities ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P8125'), ('label', 'Fandango person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P8687'), ('label', 'social media followers')]
# [('property', 'http://www.wikidata.org/prop/direct/P7105'), ('label', 'LezWatch.TV actor ID')]
# 33

# %%
# checking 'occupation' object property of the arbitrary actress (Annie Ilonzeh)
queryString = """
SELECT ?object ?label
WHERE
{
   wd:Q465556 wdt:P106 ?object.
   
   # ?object sc:name ?label.
}
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('object', 'http://www.wikidata.org/entity/Q10798782'), ('label', 'television actor')]
# [('object', 'http://www.wikidata.org/entity/Q10800557'), ('label', 'film actor')]
# [('object', 'http://www.wikidata.org/entity/Q33999'), ('label', 'actor')]
# 3

# %%
# finding an actor with its name as 'Kevin Bacon'
queryString = """
SELECT DISTINCT ?actor ?label 
WHERE
{
   # ?actor wdt:P106 wd:Q33999.
   
   FILTER REGEX(?label, "Kevin Bacon")
   
   # ?actor sc:name ?label.
}
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('actor', 'http://www.wikidata.org/entity/Q3454165'), ('label', 'Kevin Bacon')]
# 1

# %%
# finding movies or series that KB worked directly with any cast member of HIMYM (KBN=1) in them
queryString = """
SELECT ?cast_member_of_himym ?label_actor ?label_film_or_series
WHERE
{
    wd:Q147235 wdt:P161 ?cast_member_of_himym.
    
    # ?cast_member_of_himym sc:name ?label_actor.
    
    FILTER (?cast_member_of_himym = ?cast_member_of_bacon_movie)
    {
        SELECT ?cast_member_of_bacon_movie ?label_film_or_series
        WHERE
        {
            # ?film_or_series wdt:P161 ?cast_member_of_bacon_movie.
            {
                SELECT DISTINCT ?film_or_series ?label_film_or_series
                WHERE
                {
                   # ?film_or_series wdt:P161 wd:Q3454165.

                   # ?film_or_series sc:name ?label_film_or_series.
                }
            }
        }
    }
}
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('cast_member_of_himym', 'http://www.wikidata.org/entity/Q269891'), ('label_actor', 'Julianna Guill'), ('label_film_or_series', 'Crazy, Stupid, Love.')]
# [('cast_member_of_himym', 'http://www.wikidata.org/entity/Q312705'), ('label_actor', 'John Cho'), ('label_film_or_series', 'The Air I Breathe')]
# [('cast_member_of_himym', 'http://www.wikidata.org/entity/Q234715'), ('label_actor', 'Jamie-Lynn Sigler'), ('label_film_or_series', 'Skum Rocks!')]
# [('cast_member_of_himym', 'http://www.wikidata.org/entity/Q311271'), ('label_actor', 'John Lithgow'), ('label_film_or_series', 'Footloose')]
# [('cast_member_of_himym', 'http://www.wikidata.org/entity/Q234137'), ('label_actor', 'Megan Mullally'), ('label_film_or_series', 'Queens Logic')]
# [('cast_member_of_himym', 'http://www.wikidata.org/entity/Q530646'), ('label_actor', 'Ray Wise'), ('label_film_or_series', 'X-Men: First Class')]
# [('cast_member_of_himym', 'http://www.wikidata.org/entity/Q199929'), ('label_actor', 'Jennifer Morrison'), ('label_film_or_series', 'Stir of Echoes')]
# [('cast_member_of_himym', 'http://www.wikidata.org/entity/Q199929'), ('label_actor', 'Jennifer Morrison'), ('label_film_or_series', 'The Darkness')]
# [('cast_member_of_himym', 'http://www.wikidata.org/entity/Q433355'), ('label_actor', 'Patricia Belcher'), ('label_film_or_series', 'Flatliners')]
# [('cast_member_of_himym', 'http://www.wikidata.org/entity/Q234514'), ('label_actor', 'Camryn Manheim'), ('label_film_or_series', 'Cop Car')]
# [('cast_member_of_himym', 'http://www.wikidata.org/entity/Q362616'), ('label_actor', 'Jon Bernthal'), ('label_film_or_series', 'The Air I Breathe')]
# [('cast_member_of_himym', 'http://www.wikidata.org/entity/Q329744'), ('label_actor', 'Martin Short'), ('label_film_or_series', 'The Big Picture')]
# [('cast_member_of_himym', 'http://www.wikidata.org/entity/Q5357354'), ('label_actor', 'Todd Stashwick'), ('label_film_or_series', 'The Air I Breathe')]
# [('cast_member_of_himym', 'http://www.wikidata.org/entity/Q782662'), ('label_actor', 'Michael Gross'), ('label_film_or_series', 'Tremors')]
# [('cast_member_of_himym', 'http://www.wikidata.org/entity/Q268549'), ('label_actor', 'Sherri Shepherd'), ('label_film_or_series', 'Beauty Shop')]
# [('cast_member_of_himym', 'http://www.wikidata.org/entity/Q1120700'), ('label_actor', 'Orson Bean'), ('label_film_or_series', 'Forty Deuce')]
# [('cast_member_of_himym', 'http://www.wikidata.org/entity/Q1976946'), ('label_actor', 'Rachel Specter'), ('label_film_or_series', 'My One and Only')]
# 17

# %% [markdown]
# Final query for this task

# %%
# write your final query
queryString = """
SELECT DISTINCT ?cast_member_with_kbn_2 ?label
WHERE
{
    {
        ### among cast members of all films that HIMYM cast with KBN=1 has acted in, ###
        ### select those that are also a cast of HIMYM ###

        # ?film_or_series_2 wdt:P161 ?cast_member_with_kbn_2.

        FILTER (?cast_member_with_kbn_2 = ?cast_member_of_himym)

        # ?cast_member_with_kbn_2 sc:name ?label.
        {
            SELECT DISTINCT ?film_or_series_2 ?cast_member_of_himym
            WHERE
            {
                ### find all films that HIMYM cast with KBN=1 has acted in ###
                # ?film_or_series_2 wdt:P161 ?cast_member_of_himym.
                {
                    SELECT DISTINCT ?cast_member_of_himym 
                    WHERE
                    {
                        ### select those cast members of KB movies that are also cast of HIMYM ###
                        wd:Q147235 wdt:P161 ?cast_member_of_himym.

                        FILTER (?cast_member_of_himym = ?cast_member_of_bacon_movie)
                        {
                            SELECT DISTINCT ?cast_member_of_bacon_movie 
                            WHERE
                            {
                                ### find cast members (KBN=1) of all films that KB acted ###
                                # ?film_or_series wdt:P161 ?cast_member_of_bacon_movie.
                                {
                                    SELECT DISTINCT ?film_or_series 
                                    WHERE
                                    {
                                       ### find all films that KB acted ###
                                       # ?film_or_series wdt:P161 wd:Q3454165.
                                    }
                                }
                            }
                        }
                    }
                }
            }
        }
    } 
    ### exclude KBN=1 from the result because of the permutations that actors work with each other ###
    MINUS
    {
        SELECT DISTINCT ?cast_member_of_himym 
        WHERE
        {
            ### select those cast members of KB movies that are also cast of HIMYM ###
            wd:Q147235 wdt:P161 ?cast_member_of_himym.

            FILTER (?cast_member_of_himym = ?cast_member_of_bacon_movie)
            {
                SELECT DISTINCT ?cast_member_of_bacon_movie 
                WHERE
                {
                    ### find cast members (KBN=1) of all films that KB acted ###
                    # ?film_or_series wdt:P161 ?cast_member_of_bacon_movie.
                    {
                        SELECT DISTINCT ?film_or_series 
                        WHERE
                        {
                           ### find all films that KB acted ###
                           # ?film_or_series wdt:P161 wd:Q3454165.
                        }
                    }
                }
            }
        }
    }
}
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('cast_member_with_kbn_2', 'http://www.wikidata.org/entity/Q5357354'), ('label', 'Todd Stashwick')]
# 1

# %% [markdown]
# ## Task 7
# Consider the actors who are members of the cast of HIMYM. Amongst the tv series which these actors acted return only those which received more than 2 awards (the result set must be triples of tv series IRI, label, #awards won).

# %%
# write your queries
# s:HIMYM p:'instance of' o:what node?
queryString = """
SELECT ?object ?label
WHERE
{
   wd:Q147235 wdt:P31 ?object.
   
   # ?object sc:name ?label.
}
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('object', 'http://www.wikidata.org/entity/Q5398426'), ('label', 'television series')]
# 1

# %%
# getting only the television series that an arbitrary actor (Josh Radnor) has played in
queryString = """
SELECT DISTINCT ?series ?label 
WHERE
{
   # ?series wdt:P161 wd:Q223455.
   # ?series wdt:P31 wd:Q5398426.
   
   # ?series sc:name ?label.
}
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('series', 'http://www.wikidata.org/entity/Q147235'), ('label', 'How I Met Your Mother')]
# [('series', 'http://www.wikidata.org/entity/Q30607098'), ('label', 'Rise')]
# [('series', 'http://www.wikidata.org/entity/Q22074985'), ('label', 'Mercy Street')]
# 3

# %%
# getting number of awards of the node 'HIMYM'
queryString = """
SELECT wd:Q147235 ?label (COUNT (?award) AS ?num_award)
WHERE
{
   wd:Q147235 wdt:P166 ?award.
   
   wd:Q147235 sc:name ?label.
}
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('callret-0', 'http://www.wikidata.org/entity/Q147235'), ('label', 'How I Met Your Mother'), ('num_award', '7')]
# 1

# %% [markdown]
# Final query for this task

# %%
# write your final query
queryString = """
SELECT ?series_iri ?label ?num_award
WHERE
{
    FILTER (?num_award >= "2"^^xsd:integer).
    {
        SELECT ?series_iri ?label (COUNT (DISTINCT ?award) AS ?num_award)
        WHERE
        {
           wd:Q147235 wdt:P161 ?actor_iri.
           # ?series_iri wdt:P161 ?actor_iri.
           # ?series_iri wdt:P31 wd:Q5398426.
           # ?series_iri wdt:P166 ?award.

           # ?series_iri sc:name ?label.
        }
        ORDER BY DESC(?num_award)
    }
}
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('series_iri', 'http://www.wikidata.org/entity/Q23628'), ('label', 'The Sopranos'), ('num_award', '22')]
# [('series_iri', 'http://www.wikidata.org/entity/Q1079'), ('label', 'Breaking Bad'), ('num_award', '21')]
# [('series_iri', 'http://www.wikidata.org/entity/Q1132439'), ('label', 'The Practice'), ('num_award', '12')]
# [('series_iri', 'http://www.wikidata.org/entity/Q16756'), ('label', 'Modern Family'), ('num_award', '11')]
# [('series_iri', 'http://www.wikidata.org/entity/Q79784'), ('label', 'Friends'), ('num_award', '10')]
# [('series_iri', 'http://www.wikidata.org/entity/Q1136370'), ('label', 'General Hospital'), ('num_award', '10')]
# [('series_iri', 'http://www.wikidata.org/entity/Q8539'), ('label', 'The Big Bang Theory'), ('num_award', '10')]
# [('series_iri', 'http://www.wikidata.org/entity/Q244803'), ('label', 'Ally McBeal'), ('num_award', '9')]
# [('series_iri', 'http://www.wikidata.org/entity/Q438406'), ('label', "Grey's Anatomy"), ('num_award', '8')]
# [('series_iri', 'http://www.wikidata.org/entity/Q1068952'), ('label', 'St. Elsewhere'), ('num_award', '8')]
# [('series_iri', 'http://www.wikidata.org/entity/Q1030713'), ('label', 'Another World'), ('num_award', '8')]
# [('series_iri', 'http://www.wikidata.org/entity/Q147235'), ('label', 'How I Met Your Mother'), ('num_award', '7')]
# [('series_iri', 'http://www.wikidata.org/entity/Q186219'), ('label', 'True Blood'), ('num_award', '7')]
# [('series_iri', 'http://www.wikidata.org/entity/Q34659'), ('label', 'My Name Is Earl'), ('num_award', '7')]
# [('series_iri', 'http://www.wikidata.org/entity/Q117396'), ('label', 'CSI: Vegas'), ('num_award', '6')]
# [('series_iri', 'http://www.wikidata.org/entity/Q7099650'), ('label', 'Orange Is the New Black'), ('num_award', '6')]
# [('series_iri', 'http://www.wikidata.org/entity/Q2085'), ('label', 'Twin Peaks'), ('num_award', '6')]
# [('series_iri', 'http://www.wikidata.org/entity/Q1168760'), ('label', 'Upstairs, Downstairs'), ('num_award', '5')]
# [('series_iri', 'http://www.wikidata.org/entity/Q833322'), ('label', 'Murder, She Wrote'), ('num_award', '4')]
# [('series_iri', 'http://www.wikidata.org/entity/Q30603704'), ('label', 'Pose'), ('num_award', '3')]
# [('series_iri', 'http://www.wikidata.org/entity/Q1144624'), ('label', 'Family Ties'), ('num_award', '3')]
# [('series_iri', 'http://www.wikidata.org/entity/Q19570'), ('label', 'The Good Wife'), ('num_award', '3')]
# [('series_iri', 'http://www.wikidata.org/entity/Q232737'), ('label', 'The Walking Dead'), ('num_award', '3')]
# [('series_iri', 'http://www.wikidata.org/entity/Q7103920'), ('label', 'Orphan Black'), ('num_award', '2')]
# [('series_iri', 'http://www.wikidata.org/entity/Q23594'), ('label', 'Homeland'), ('num_award', '2')]
# [('series_iri', 'http://www.wikidata.org/entity/Q1122661'), ('label', 'Project Runway'), ('num_award', '2')]
# [('series_iri', 'http://www.wikidata.org/entity/Q647001'), ('label', 'Dr. Quinn, Medicine Woman'), ('num_award', '2')]
# [('series_iri', 'http://www.wikidata.org/entity/Q23609'), ('label', 'Weeds'), ('num_award', '2')]
# 28

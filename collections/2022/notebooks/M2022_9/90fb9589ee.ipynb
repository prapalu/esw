# %% [markdown]
# # General instructions
#
# The goal of the project is to materialize a set of **exploratory workloads** over a real-world, large-scale,  open-domain KG: [WikiData](https://www.wikidata.org/wiki/Wikidata:Main_Page)
#
# An exploratory workload  is composed by a set of queries, where each query is related to the information obtained previously.
#
# An exploratory workload starts with a usually vague, open ended question, and does not assume the person issuing the workload has a clear understanding of the data contained in the target database or its structure.
#
# Remeber that:
#
# 1. All the queries must run in the python notebook
# 2. You can use classes and properties only if you find them via a SPARQL query that must be present in the notebook
# 3. You do not delete useless queries. Keep everything that is synthatically valid
#
# ```
# ?p <http://schema.org/name> ?name .
# ```
#
#     is the BGP returning a human-readable name of a property or a class in Wikidata.

# %%
## SETUP used later

from SPARQLWrapper import SPARQLWrapper, JSON


prefixString = """
##-90fb9589ee-##
PREFIX wd: <http://www.wikidata.org/entity/> 
PREFIX wdt: <http://www.wikidata.org/prop/direct/> 
PREFIX sc: <http://schema.org/>
"""

# select and construct queries
def run_query(queryString,verbose = True):
    to_run = prefixString + "\n" + queryString

    sparql = SPARQLWrapper("http://a256-gc1-03.srv.aau.dk:5820/sparql")
    sparql.setTimeout(300)
    sparql.setReturnFormat(JSON)
    sparql.setQuery(to_run)

    try :
        results = sparql.query()
        json_results = results.convert()
        if len(json_results['results']['bindings'])==0:
            print("Empty")
            return []
        array = []
        for bindings in json_results['results']['bindings']:
            app =  [ (var, value['value'])  for var, value in bindings.items() ] 
            if verbose:
                print( app)
            array.append(app)
        if verbose:
            print(len(array))
        return array

    except Exception as e :
        print("The operation failed", e)
    
# ASk queries
def run_ask_query(queryString):
    to_run = prefixString + "\n" + queryString

    sparql = SPARQLWrapper("http://a256-gc1-03.srv.aau.dk:5820/sparql")
    sparql.setTimeout(300)
    sparql.setReturnFormat(JSON)
    sparql.setQuery(to_run)

    try :
        return sparql.query().convert()

    except Exception as e :
        print("The operation failed", e)
# Out:
# The history saving thread hit an unexpected error (OperationalError('attempt to write a readonly database')).History will not be written to the database.

# %% [markdown]
# # History Workflow Series ("Cultural Movements explorative search")
#
# Consider the following exploratory information need:
#
# > investigate the cultural movements, in particular the Renaissance, Baroque and Romanticsm. We'd like to get an overview of the main artists belonging to these movements, musicians, poets, sculptors and painters.

# %% [markdown]
# ## Useful URIs for the current workflow
# The following are given:
#
# | IRI           | Description   | Role      |
# | -----------   | -----------   |-----------|
# | `wdt:P1647`   | subproperty   | predicate |
# | `wdt:P31`     | instance of   | predicate |
# | `wdt:P106`    | occupation    | predicate |
# | `wdt:P279`    | subclass      | predicate |
# | `wdt:P27`     | nationality   | predicate |
# | `wdt:P3342`     | Significant person       | predicate |
# | `wd:Q5`| Human       | node |
# | `wd:Q37562`| Donatello    | node |
# | `wd:Q19675`| Louvre Museum | node |

# %% [markdown]
# Also consider
#
# ```
# wd:Q37562 ?p ?obj .
# ```
#
# is the BGP to retrieve all **properties of Donatello**
#
# Please consider that when you return a resource, you should return the IRI and the label of the resource. In particular, when the task require you to identify a BGP the result set must always be a list of couples IRI - label.
#
# The workload should:
#
#
# 1. Identify the BGP for Cultural Movement
#
# 2. Identify the BGP for Renassaince, Baroque and Romanticism
#
# 3. Identify the BGP for composer, painter, sculptor and poet
#
# 4. Consider Renaissance, Baroque and Romanticism. Find how many composers, painters, sculptors and poets belong to those cultural movements (the results set must be a list of triples movement, job, #people)
#
# 5. Find how many sculptures were made in Italy during Renaissance, Baroque, and Romanticism movements. Please consider all the sculptures and all the sculpture subtypes. (the result set must be a list of triples movement IRI, label and #sculptures).
#
# 6. For each European country find how many poets belong to Romanticism (the result set must be a list of triples country IRI, label and #poets).
#
# 7. Find the number of sculptures in the Louvre Museum belonging to Renaissance, Baroque, or Romanticism (return a number for each movement) (the result set must be a list of triples movement IRI, label and #sculptures).

# %% [markdown]
# ## Task 1
# Identify the BGP for Cultural Movement

# %%
# query example
queryString = """
SELECT DISTINCT ?p ?name
WHERE {
   # bind something
   wd:Q37562 ?p ?obj .
   # get the label
   # ?p sc:name ?name.
   
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P1005'), ('name', 'Portuguese National Library ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1006'), ('name', 'Nationale Thesaurus voor Auteurs ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P101'), ('name', 'field of work')]
# [('p', 'http://www.wikidata.org/prop/direct/P1015'), ('name', 'NORAF ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1017'), ('name', 'Vatican Library ID (former scheme)')]
# [('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('p', 'http://www.wikidata.org/prop/direct/P1066'), ('name', 'student of')]
# [('p', 'http://www.wikidata.org/prop/direct/P1138'), ('name', 'Kunstindeks Danmark Artist ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P119'), ('name', 'place of burial')]
# [('p', 'http://www.wikidata.org/prop/direct/P1207'), ('name', 'NUKAT ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1248'), ('name', 'KulturNav-ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1263'), ('name', 'NNDB people ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1273'), ('name', 'CANTIC ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1280'), ('name', 'CONOR.SI ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1296'), ('name', 'Gran Enciclopèdia Catalana ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1315'), ('name', 'NLA Trove ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1343'), ('name', 'described by source')]
# [('p', 'http://www.wikidata.org/prop/direct/P135'), ('name', 'movement')]
# [('p', 'http://www.wikidata.org/prop/direct/P136'), ('name', 'genre')]
# [('p', 'http://www.wikidata.org/prop/direct/P1367'), ('name', 'Art UK artist ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1368'), ('name', 'LNB ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1412'), ('name', 'languages spoken, written or signed')]
# [('p', 'http://www.wikidata.org/prop/direct/P1417'), ('name', 'Encyclopædia Britannica Online ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1422'), ('name', 'Sandrart.net person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1472'), ('name', 'Commons Creator page')]
# [('p', 'http://www.wikidata.org/prop/direct/P1580'), ('name', 'University of Barcelona authority ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1711'), ('name', 'British Museum person or institution ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P172'), ('name', 'ethnic group')]
# [('p', 'http://www.wikidata.org/prop/direct/P18'), ('name', 'image')]
# [('p', 'http://www.wikidata.org/prop/direct/P1871'), ('name', 'CERL Thesaurus ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1882'), ('name', 'Web Gallery of Art ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P19'), ('name', 'place of birth')]
# [('p', 'http://www.wikidata.org/prop/direct/P1986'), ('name', 'Biographical Dictionary of Italian People ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P20'), ('name', 'place of death')]
# [('p', 'http://www.wikidata.org/prop/direct/P2042'), ('name', 'Artsy artist ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P21'), ('name', 'sex or gender')]
# [('p', 'http://www.wikidata.org/prop/direct/P213'), ('name', 'ISNI')]
# [('p', 'http://www.wikidata.org/prop/direct/P214'), ('name', 'VIAF ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2163'), ('name', 'FAST ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2252'), ('name', 'National Gallery of Art artist ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P227'), ('name', 'GND ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2342'), ('name', 'AGORHA person/institution ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P244'), ('name', 'Library of Congress authority ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P245'), ('name', 'Union List of Artist Names ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2538'), ('name', 'Nationalmuseum Sweden actor ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2600'), ('name', 'Geni.com profile ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P268'), ('name', 'Bibliothèque nationale de France ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P269'), ('name', 'IdRef ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P27'), ('name', 'country of citizenship')]
# [('p', 'http://www.wikidata.org/prop/direct/P271'), ('name', 'CiNii author ID (books)')]
# [('p', 'http://www.wikidata.org/prop/direct/P2732'), ('name', 'Persée author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2843'), ('name', 'Benezit ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2924'), ('name', 'Great Russian Encyclopedia Online ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2949'), ('name', 'WikiTree person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('name', 'instance of')]
# [('p', 'http://www.wikidata.org/prop/direct/P3219'), ('name', 'Encyclopædia Universalis ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3222'), ('name', 'NE.se ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3241'), ('name', 'Catholic Encyclopedia ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3365'), ('name', 'Treccani ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3430'), ('name', 'SNAC ARK ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P349'), ('name', 'National Diet Library ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P373'), ('name', 'Commons category')]
# [('p', 'http://www.wikidata.org/prop/direct/P3782'), ('name', 'Artnet artist ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3791'), ('name', 'Art Renewal Center artist ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3888'), ('name', 'Boijmans artist ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P396'), ('name', 'SBN author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3987'), ('name', 'SHARE Catalogue author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P409'), ('name', 'Libraries Australia ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P4145'), ('name', 'Athenaeum person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P4223'), ('name', "Treccani's Enciclopedia Italiana ID")]
# [('p', 'http://www.wikidata.org/prop/direct/P4553'), ('name', 'RA Collections ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P4808'), ('name', 'Royal Academy new identifier')]
# [('p', 'http://www.wikidata.org/prop/direct/P4927'), ('name', 'Invaluable.com person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5008'), ('name', 'on focus list of Wikimedia project')]
# [('p', 'http://www.wikidata.org/prop/direct/P5019'), ('name', 'Brockhaus Enzyklopädie online ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5063'), ('name', 'Interlingual Index ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P535'), ('name', 'Find A Grave memorial ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5587'), ('name', 'Libris-URI')]
# [('p', 'http://www.wikidata.org/prop/direct/P5597'), ('name', 'Artcyclopedia artist ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P569'), ('name', 'date of birth')]
# [('p', 'http://www.wikidata.org/prop/direct/P570'), ('name', 'date of death')]
# [('p', 'http://www.wikidata.org/prop/direct/P6002'), ('name', 'WikiArt ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6379'), ('name', 'has works in the collection')]
# [('p', 'http://www.wikidata.org/prop/direct/P6394'), ('name', 'ELNET ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P646'), ('name', 'Freebase ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P648'), ('name', 'Open Library ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P650'), ('name', 'RKDartists ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6656'), ('name', 'BHCL ID (former scheme)')]
# [('p', 'http://www.wikidata.org/prop/direct/P6706'), ('name', 'De Agostini ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6844'), ('name', 'abART person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P691'), ('name', 'NKCR AUT ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7293'), ('name', 'PLWABN ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P734'), ('name', 'family name')]
# [('p', 'http://www.wikidata.org/prop/direct/P735'), ('name', 'given name')]
# [('p', 'http://www.wikidata.org/prop/direct/P7444'), ('name', 'Rijksmuseum Research Library authority ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7666'), ('name', 'Visuotinė lietuvių enciklopedija ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7699'), ('name', 'National Library of Lithuania ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7704'), ('name', 'Europeana entity')]
# [('p', 'http://www.wikidata.org/prop/direct/P7711'), ('name', 'Joconde author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7763'), ('name', 'copyright status as a creator')]
# 100

# %%
#[('p', 'http://www.wikidata.org/prop/direct/P135'), ('name', 'movement')]

queryString = """
SELECT DISTINCT ?p ?name
WHERE {
   # bind something
   wd:Q37562 wdt:P135 ?p .
   # get the label
   # ?p sc:name ?name.
   
   
  # filter(regex(?name,"cultural movement"))
  #propertysysubjectkesenikalen
   
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/entity/Q1472236'), ('name', 'Early Renaissance')]
# 1

# %% [markdown]
# Final query for this task

# %%
#[('p', 'http://www.wikidata.org/entity/Q1472236'), ('name', 'Early Renaissance')]
queryString = """
SELECT DISTINCT ?p ?name ?o ?nm
WHERE {
   # bind something
   wd:Q1472236 ?o ?p .
   # get the label
   # ?p sc:name ?name.
   
   

   
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/entity/Q11514315'), ('name', 'historical period'), ('o', 'http://www.wikidata.org/prop/direct/P31')]
# [('p', 'http://www.wikidata.org/entity/Q1474884'), ('name', 'High Renaissance'), ('o', 'http://www.wikidata.org/prop/direct/P156')]
# [('p', 'http://www.wikidata.org/entity/Q4692'), ('name', 'Renaissance'), ('o', 'http://www.wikidata.org/prop/direct/P361')]
# [('p', 'http://www.wikidata.org/entity/Q968159'), ('name', 'art movement'), ('o', 'http://www.wikidata.org/prop/direct/P31')]
# [('p', 'http://www.wikidata.org/entity/Q979160'), ('name', 'Proto-Renaissance'), ('o', 'http://www.wikidata.org/prop/direct/P155')]
# 5

# %%
#[('p', 'http://www.wikidata.org/entity/Q1472236'), ('name', 'Early Renaissance')]
#[('p', 'http://www.wikidata.org/entity/Q4692'), ('name', 'Renaissance'),


queryString = """
SELECT DISTINCT ?p ?name ?o ?nm
WHERE {
   # bind something
   wd:Q4692 ?o ?p .
   # get the label
   # ?p sc:name ?name.
   
   

   
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/entity/Q13830551'), ('name', 'Portal:Renaissance'), ('o', 'http://www.wikidata.org/prop/direct/P1151')]
# [('p', 'http://www.wikidata.org/entity/Q15885248'), ('name', 'Renaissance painting'), ('o', 'http://www.wikidata.org/prop/direct/P527')]
# [('p', 'http://www.wikidata.org/entity/Q1781608'), ('name', 'Renaissance literature'), ('o', 'http://www.wikidata.org/prop/direct/P527')]
# [('p', 'http://www.wikidata.org/entity/Q1404472'), ('name', 'Italian Renaissance'), ('o', 'http://www.wikidata.org/prop/direct/P527')]
# [('p', 'http://www.wikidata.org/entity/Q1472236'), ('name', 'Early Renaissance'), ('o', 'http://www.wikidata.org/prop/direct/P527')]
# [('p', 'http://www.wikidata.org/entity/Q1474884'), ('name', 'High Renaissance'), ('o', 'http://www.wikidata.org/prop/direct/P527')]
# [('p', 'http://www.wikidata.org/entity/Q2041543'), ('name', 'Ottův slovník naučný'), ('o', 'http://www.wikidata.org/prop/direct/P1343')]
# [('p', 'http://www.wikidata.org/entity/Q27496'), ('name', 'Western Europe'), ('o', 'http://www.wikidata.org/prop/direct/P276')]
# [('p', 'http://www.wikidata.org/entity/Q3181656'), ('name', 'The Nuttall Encyclopædia'), ('o', 'http://www.wikidata.org/prop/direct/P1343')]
# [('p', 'http://www.wikidata.org/entity/Q37853'), ('name', 'Baroque'), ('o', 'http://www.wikidata.org/prop/direct/P156')]
# [('p', 'http://www.wikidata.org/entity/Q5460604'), ('name', 'Wikipedia:Vital articles'), ('o', 'http://www.wikidata.org/prop/direct/P5008')]
# [('p', 'http://www.wikidata.org/entity/Q602358'), ('name', 'Brockhaus and Efron Encyclopedic Dictionary'), ('o', 'http://www.wikidata.org/prop/direct/P1343')]
# [('p', 'http://www.wikidata.org/entity/Q236122'), ('name', 'Renaissance architecture'), ('o', 'http://www.wikidata.org/prop/direct/P527')]
# [('p', 'http://www.wikidata.org/entity/Q32880'), ('name', 'architectural style'), ('o', 'http://www.wikidata.org/prop/direct/P31')]
# [('p', 'http://www.wikidata.org/entity/Q968159'), ('name', 'art movement'), ('o', 'http://www.wikidata.org/prop/direct/P31')]
# [('p', 'http://www.wikidata.org/entity/Q12554'), ('name', 'Middle Ages'), ('o', 'http://www.wikidata.org/prop/direct/P155')]
# [('p', 'http://www.wikidata.org/entity/Q201405'), ('name', 'Renaissance music'), ('o', 'http://www.wikidata.org/prop/direct/P527')]
# [('p', 'http://www.wikidata.org/entity/Q2198855'), ('name', 'cultural movement'), ('o', 'http://www.wikidata.org/prop/direct/P31')]
# [('p', 'http://www.wikidata.org/entity/Q46825'), ('name', 'Gothic art'), ('o', 'http://www.wikidata.org/prop/direct/P155')]
# [('p', 'http://www.wikidata.org/entity/Q1133779'), ('name', 'Renaissance art'), ('o', 'http://www.wikidata.org/prop/direct/P527')]
# [('p', 'http://www.wikidata.org/entity/Q936588'), ('name', 'Renaissance sculpture'), ('o', 'http://www.wikidata.org/prop/direct/P527')]
# [('p', 'http://www.wikidata.org/entity/Q25111456'), ('name', 'Renaissance studies'), ('o', 'http://www.wikidata.org/prop/direct/P2579')]
# [('p', 'http://www.wikidata.org/entity/Q978825'), ('name', 'Renaissance dance'), ('o', 'http://www.wikidata.org/prop/direct/P527')]
# [('p', 'http://www.wikidata.org/entity/Q979160'), ('name', 'Proto-Renaissance'), ('o', 'http://www.wikidata.org/prop/direct/P527')]
# [('p', 'http://www.wikidata.org/entity/Q10999203'), ('name', 'Template:Renaissance'), ('o', 'http://www.wikidata.org/prop/direct/P1424')]
# [('p', 'http://www.wikidata.org/entity/Q13400700'), ('name', 'Renaissance'), ('o', 'http://www.wikidata.org/prop/direct/P1889')]
# [('p', 'http://www.wikidata.org/entity/Q8651924'), ('name', 'Category:Renaissance'), ('o', 'http://www.wikidata.org/prop/direct/P910')]
# [('p', 'http://www.wikidata.org/entity/Q7112776'), ('name', 'outline of the Renaissance'), ('o', 'http://www.wikidata.org/prop/direct/P5125')]
# 28

# %%
#final query task 1 BGP OF CULTURAL MOVEMENT.
#[('p', 'http://www.wikidata.org/entity/Q2198855'), ('name', 'cultural movement')
#[('p', 'http://www.wikidata.org/entity/Q1472236'), ('name', 'Early Renaissance')]
#[('p', 'http://www.wikidata.org/entity/Q4692'), ('name', 'Renaissance'),


queryString = """
SELECT DISTINCT ?p ?name ?o ?nm
WHERE {
   # bind something
   wd:Q2198855 ?o ?p .
   # get the label
   # ?p sc:name ?name.
   
   

   
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/entity/P135'), ('name', 'movement'), ('o', 'http://www.wikidata.org/prop/direct/P1687')]
# [('p', 'http://www.wikidata.org/entity/Q49773'), ('name', 'social movement'), ('o', 'http://www.wikidata.org/prop/direct/P279')]
# [('p', 'http://www.wikidata.org/entity/Q3533467'), ('name', 'group action'), ('o', 'http://www.wikidata.org/prop/direct/P279')]
# [('p', 'http://www.wikidata.org/entity/Q6638204'), ('name', 'Category:Cultural movement'), ('o', 'http://www.wikidata.org/prop/direct/P910')]
# 4

# %% [markdown]
# ## Task 2
# Identify the BGP for Renassaince, Baroque and Romanticism

# %%
# FOR RENASSAINCE
#[('p', 'http://www.wikidata.org/entity/Q1472236'), ('name', 'Early Renaissance')]
queryString = """
SELECT DISTINCT ?p ?name
WHERE {
   # bind something
   wd:Q1472236 ?p ?o .
   # get the label
   # ?p sc:name ?name.
   

   
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P1014'), ('name', 'Art & Architecture Thesaurus ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1417'), ('name', 'Encyclopædia Britannica Online ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P155'), ('name', 'follows')]
# [('p', 'http://www.wikidata.org/prop/direct/P156'), ('name', 'followed by')]
# [('p', 'http://www.wikidata.org/prop/direct/P2347'), ('name', 'YSO ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2671'), ('name', 'Google Knowledge Graph ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('name', 'instance of')]
# [('p', 'http://www.wikidata.org/prop/direct/P361'), ('name', 'part of')]
# [('p', 'http://www.wikidata.org/prop/direct/P5604'), ('name', 'archINFORM keyword ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P571'), ('name', 'inception')]
# [('p', 'http://www.wikidata.org/prop/direct/P576'), ('name', 'dissolved, abolished or demolished date')]
# [('p', 'http://www.wikidata.org/prop/direct/P580'), ('name', 'start time')]
# [('p', 'http://www.wikidata.org/prop/direct/P582'), ('name', 'end time')]
# [('p', 'http://www.wikidata.org/prop/direct/P910'), ('name', "topic's main category")]
# 14

# %%
# write your queries
#[('p', 'http://www.wikidata.org/entity/Q1472236'), ('name', 'Early Renaissance')]
queryString = """
SELECT DISTINCT ?p ?name ?o ?nm
WHERE {
   # bind something
   wd:Q1472236 ?o ?p .
   # get the label
   # ?p sc:name ?name.
   
   

   
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/entity/Q11514315'), ('name', 'historical period'), ('o', 'http://www.wikidata.org/prop/direct/P31')]
# [('p', 'http://www.wikidata.org/entity/Q1474884'), ('name', 'High Renaissance'), ('o', 'http://www.wikidata.org/prop/direct/P156')]
# [('p', 'http://www.wikidata.org/entity/Q4692'), ('name', 'Renaissance'), ('o', 'http://www.wikidata.org/prop/direct/P361')]
# [('p', 'http://www.wikidata.org/entity/Q968159'), ('name', 'art movement'), ('o', 'http://www.wikidata.org/prop/direct/P31')]
# [('p', 'http://www.wikidata.org/entity/Q979160'), ('name', 'Proto-Renaissance'), ('o', 'http://www.wikidata.org/prop/direct/P155')]
# 5

# %% [markdown]
# Final query for this task

# %%
# BGP OF RENAISSANCE
#[('p', 'http://www.wikidata.org/entity/Q1472236'), ('name', 'Early Renaissance')]
#[('p', 'http://www.wikidata.org/entity/Q4692'), ('name', 'Renaissance'),


queryString = """
SELECT DISTINCT ?p ?name ?o ?nm
WHERE {
   # bind something
   wd:Q4692 ?o ?p .
   # get the label
   # ?p sc:name ?name.
   
   

   
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/entity/Q13830551'), ('name', 'Portal:Renaissance'), ('o', 'http://www.wikidata.org/prop/direct/P1151')]
# [('p', 'http://www.wikidata.org/entity/Q15885248'), ('name', 'Renaissance painting'), ('o', 'http://www.wikidata.org/prop/direct/P527')]
# [('p', 'http://www.wikidata.org/entity/Q1781608'), ('name', 'Renaissance literature'), ('o', 'http://www.wikidata.org/prop/direct/P527')]
# [('p', 'http://www.wikidata.org/entity/Q1404472'), ('name', 'Italian Renaissance'), ('o', 'http://www.wikidata.org/prop/direct/P527')]
# [('p', 'http://www.wikidata.org/entity/Q1472236'), ('name', 'Early Renaissance'), ('o', 'http://www.wikidata.org/prop/direct/P527')]
# [('p', 'http://www.wikidata.org/entity/Q1474884'), ('name', 'High Renaissance'), ('o', 'http://www.wikidata.org/prop/direct/P527')]
# [('p', 'http://www.wikidata.org/entity/Q2041543'), ('name', 'Ottův slovník naučný'), ('o', 'http://www.wikidata.org/prop/direct/P1343')]
# [('p', 'http://www.wikidata.org/entity/Q27496'), ('name', 'Western Europe'), ('o', 'http://www.wikidata.org/prop/direct/P276')]
# [('p', 'http://www.wikidata.org/entity/Q3181656'), ('name', 'The Nuttall Encyclopædia'), ('o', 'http://www.wikidata.org/prop/direct/P1343')]
# [('p', 'http://www.wikidata.org/entity/Q37853'), ('name', 'Baroque'), ('o', 'http://www.wikidata.org/prop/direct/P156')]
# [('p', 'http://www.wikidata.org/entity/Q5460604'), ('name', 'Wikipedia:Vital articles'), ('o', 'http://www.wikidata.org/prop/direct/P5008')]
# [('p', 'http://www.wikidata.org/entity/Q602358'), ('name', 'Brockhaus and Efron Encyclopedic Dictionary'), ('o', 'http://www.wikidata.org/prop/direct/P1343')]
# [('p', 'http://www.wikidata.org/entity/Q236122'), ('name', 'Renaissance architecture'), ('o', 'http://www.wikidata.org/prop/direct/P527')]
# [('p', 'http://www.wikidata.org/entity/Q32880'), ('name', 'architectural style'), ('o', 'http://www.wikidata.org/prop/direct/P31')]
# [('p', 'http://www.wikidata.org/entity/Q968159'), ('name', 'art movement'), ('o', 'http://www.wikidata.org/prop/direct/P31')]
# [('p', 'http://www.wikidata.org/entity/Q12554'), ('name', 'Middle Ages'), ('o', 'http://www.wikidata.org/prop/direct/P155')]
# [('p', 'http://www.wikidata.org/entity/Q201405'), ('name', 'Renaissance music'), ('o', 'http://www.wikidata.org/prop/direct/P527')]
# [('p', 'http://www.wikidata.org/entity/Q2198855'), ('name', 'cultural movement'), ('o', 'http://www.wikidata.org/prop/direct/P31')]
# [('p', 'http://www.wikidata.org/entity/Q46825'), ('name', 'Gothic art'), ('o', 'http://www.wikidata.org/prop/direct/P155')]
# [('p', 'http://www.wikidata.org/entity/Q1133779'), ('name', 'Renaissance art'), ('o', 'http://www.wikidata.org/prop/direct/P527')]
# [('p', 'http://www.wikidata.org/entity/Q936588'), ('name', 'Renaissance sculpture'), ('o', 'http://www.wikidata.org/prop/direct/P527')]
# [('p', 'http://www.wikidata.org/entity/Q25111456'), ('name', 'Renaissance studies'), ('o', 'http://www.wikidata.org/prop/direct/P2579')]
# [('p', 'http://www.wikidata.org/entity/Q978825'), ('name', 'Renaissance dance'), ('o', 'http://www.wikidata.org/prop/direct/P527')]
# [('p', 'http://www.wikidata.org/entity/Q979160'), ('name', 'Proto-Renaissance'), ('o', 'http://www.wikidata.org/prop/direct/P527')]
# [('p', 'http://www.wikidata.org/entity/Q10999203'), ('name', 'Template:Renaissance'), ('o', 'http://www.wikidata.org/prop/direct/P1424')]
# [('p', 'http://www.wikidata.org/entity/Q13400700'), ('name', 'Renaissance'), ('o', 'http://www.wikidata.org/prop/direct/P1889')]
# [('p', 'http://www.wikidata.org/entity/Q8651924'), ('name', 'Category:Renaissance'), ('o', 'http://www.wikidata.org/prop/direct/P910')]
# [('p', 'http://www.wikidata.org/entity/Q7112776'), ('name', 'outline of the Renaissance'), ('o', 'http://www.wikidata.org/prop/direct/P5125')]
# 28

# %%
# BGP OF BAROQUE
#[('p', 'http://www.wikidata.org/entity/Q37853'), ('name', 'Baroque'),


queryString = """
SELECT DISTINCT ?p ?name ?o ?nm
WHERE {
   # bind something
   wd:Q37853 ?o ?p .
   # get the label
   # ?p sc:name ?name.
   
   

   
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/entity/Q172991'), ('name', 'Council of Trent'), ('o', 'http://www.wikidata.org/prop/direct/P737')]
# [('p', 'http://www.wikidata.org/entity/Q11514315'), ('name', 'historical period'), ('o', 'http://www.wikidata.org/prop/direct/P31')]
# [('p', 'http://www.wikidata.org/entity/Q1292119'), ('name', 'style'), ('o', 'http://www.wikidata.org/prop/direct/P31')]
# [('p', 'http://www.wikidata.org/entity/Q131808'), ('name', 'Mannerism'), ('o', 'http://www.wikidata.org/prop/direct/P155')]
# [('p', 'http://www.wikidata.org/entity/Q2041543'), ('name', 'Ottův slovník naučný'), ('o', 'http://www.wikidata.org/prop/direct/P1343')]
# [('p', 'http://www.wikidata.org/entity/Q2657718'), ('name', 'Armenian Soviet Encyclopedia'), ('o', 'http://www.wikidata.org/prop/direct/P1343')]
# [('p', 'http://www.wikidata.org/entity/Q3181656'), ('name', 'The Nuttall Encyclopædia'), ('o', 'http://www.wikidata.org/prop/direct/P1343')]
# [('p', 'http://www.wikidata.org/entity/Q32880'), ('name', 'architectural style'), ('o', 'http://www.wikidata.org/prop/direct/P31')]
# [('p', 'http://www.wikidata.org/entity/Q4692'), ('name', 'Renaissance'), ('o', 'http://www.wikidata.org/prop/direct/P155')]
# [('p', 'http://www.wikidata.org/entity/Q968159'), ('name', 'art movement'), ('o', 'http://www.wikidata.org/prop/direct/P31')]
# [('p', 'http://www.wikidata.org/entity/Q2198855'), ('name', 'cultural movement'), ('o', 'http://www.wikidata.org/prop/direct/P31')]
# [('p', 'http://www.wikidata.org/entity/Q1431376'), ('name', 'Baroque literature'), ('o', 'http://www.wikidata.org/prop/direct/P527')]
# [('p', 'http://www.wikidata.org/entity/Q3624106'), ('name', 'Baroque art'), ('o', 'http://www.wikidata.org/prop/direct/P527')]
# [('p', 'http://www.wikidata.org/entity/Q63442026'), ('name', 'High Baroque'), ('o', 'http://www.wikidata.org/prop/direct/P527')]
# [('p', 'http://www.wikidata.org/entity/Q8810374'), ('name', 'Category:Baroque'), ('o', 'http://www.wikidata.org/prop/direct/P910')]
# 15

# %%
#exploring cultural movement fpr romanticism
#[('p', 'http://www.wikidata.org/entity/Q2198855'), ('name', 'cultural movement')


queryString = """
SELECT DISTINCT ?p ?name ?o ?nm
WHERE {
   # bind something
   # ?p wdt:P31 wd:Q2198855 .
   # get the label
   # ?p sc:name ?name.
   
   

   
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/entity/Q8210150'), ('name', 'Avanzada Regia')]
# [('p', 'http://www.wikidata.org/entity/Q211481'), ('name', 'Dogme 95')]
# [('p', 'http://www.wikidata.org/entity/Q2046861'), ('name', 'Palaeologan Renaissance')]
# [('p', 'http://www.wikidata.org/entity/Q1400430'), ('name', 'Macedonian Renaissance')]
# [('p', 'http://www.wikidata.org/entity/Q430167'), ('name', 'Spanish Renaissance')]
# [('p', 'http://www.wikidata.org/entity/Q1814286'), ('name', 'Young Estonia')]
# [('p', 'http://www.wikidata.org/entity/Q2614483'), ('name', 'Pre-romanticism')]
# [('p', 'http://www.wikidata.org/entity/Q39427'), ('name', 'surrealism')]
# [('p', 'http://www.wikidata.org/entity/Q2349908'), ('name', 'French Renaissance')]
# [('p', 'http://www.wikidata.org/entity/Q878985'), ('name', 'modernism')]
# [('p', 'http://www.wikidata.org/entity/Q466887'), ('name', 'Belle Époque')]
# [('p', 'http://www.wikidata.org/entity/Q12539'), ('name', 'Age of Enlightenment')]
# [('p', 'http://www.wikidata.org/entity/Q265581'), ('name', 'fin de siècle')]
# [('p', 'http://www.wikidata.org/entity/Q42865'), ('name', 'Orientalism')]
# [('p', 'http://www.wikidata.org/entity/Q934618'), ('name', 'Danish Golden Age')]
# [('p', 'http://www.wikidata.org/entity/Q3488076'), ('name', 'La Sape')]
# [('p', 'http://www.wikidata.org/entity/Q3083331'), ('name', 'Andean Baroque')]
# [('p', 'http://www.wikidata.org/entity/Q1753636'), ('name', 'Gilded Age')]
# [('p', 'http://www.wikidata.org/entity/Q131808'), ('name', 'Mannerism')]
# [('p', 'http://www.wikidata.org/entity/Q1404472'), ('name', 'Italian Renaissance')]
# [('p', 'http://www.wikidata.org/entity/Q37068'), ('name', 'Romanticism')]
# [('p', 'http://www.wikidata.org/entity/Q37853'), ('name', 'Baroque')]
# [('p', 'http://www.wikidata.org/entity/Q751880'), ('name', 'japonism')]
# [('p', 'http://www.wikidata.org/entity/Q620629'), ('name', 'deism')]
# [('p', 'http://www.wikidata.org/entity/Q4692'), ('name', 'Renaissance')]
# [('p', 'http://www.wikidata.org/entity/Q744738'), ('name', 'encyclopédistes')]
# [('p', 'http://www.wikidata.org/entity/Q863679'), ('name', 'chinoiserie')]
# [('p', 'http://www.wikidata.org/entity/Q4745501'), ('name', 'American modernism')]
# [('p', 'http://www.wikidata.org/entity/Q164800'), ('name', 'Symbolism')]
# [('p', 'http://www.wikidata.org/entity/Q5653011'), ('name', 'North Group')]
# [('p', 'http://www.wikidata.org/entity/Q6034'), ('name', 'Dada')]
# [('p', 'http://www.wikidata.org/entity/Q466521'), ('name', 'kinetic art')]
# [('p', 'http://www.wikidata.org/entity/Q374278'), ('name', 'agitprop')]
# [('p', 'http://www.wikidata.org/entity/Q940595'), ('name', 'Zutiste')]
# [('p', 'http://www.wikidata.org/entity/Q2896922'), ('name', 'Berberism')]
# [('p', 'http://www.wikidata.org/entity/Q846933'), ('name', 'renaissance humanism')]
# [('p', 'http://www.wikidata.org/entity/Q194100'), ('name', 'transhumanism')]
# [('p', 'http://www.wikidata.org/entity/Q9033935'), ('name', 'Brazilian modernism')]
# [('p', 'http://www.wikidata.org/entity/Q2390991'), ('name', 'Gothicismus')]
# [('p', 'http://www.wikidata.org/entity/Q1347824'), ('name', 'La Movida Madrileña')]
# [('p', 'http://www.wikidata.org/entity/Q3424747'), ('name', 'Modern Greek Enlightenment')]
# [('p', 'http://www.wikidata.org/entity/Q3482195'), ('name', 'shingeki')]
# [('p', 'http://www.wikidata.org/entity/Q472670'), ('name', 'Haskalah')]
# [('p', 'http://www.wikidata.org/entity/Q64528910'), ('name', 'The Forge')]
# [('p', 'http://www.wikidata.org/entity/Q3362516'), ('name', 'Afrofuturism')]
# [('p', 'http://www.wikidata.org/entity/Q1759189'), ('name', 'mangue bit')]
# [('p', 'http://www.wikidata.org/entity/Q10468834'), ('name', 'White cube gallery')]
# [('p', 'http://www.wikidata.org/entity/Q89099707'), ('name', 'Özgün müzik')]
# [('p', 'http://www.wikidata.org/entity/Q478004'), ('name', 'anti-clericalism')]
# [('p', 'http://www.wikidata.org/entity/Q10936092'), ('name', 'Taisho Roman')]
# [('p', 'http://www.wikidata.org/entity/Q1580216'), ('name', 'Noucentisme')]
# [('p', 'http://www.wikidata.org/entity/Q160476'), ('name', 'German Expressionism')]
# [('p', 'http://www.wikidata.org/entity/Q2639653'), ('name', 'Leonese regionalism')]
# [('p', 'http://www.wikidata.org/entity/Q64761829'), ('name', 'New Drama')]
# [('p', 'http://www.wikidata.org/entity/Q15991289'), ('name', 'Old School Renaissance')]
# [('p', 'http://www.wikidata.org/entity/Q16573056'), ('name', 'Guardia Vieja')]
# [('p', 'http://www.wikidata.org/entity/Q3298288'), ('name', 'post-postmodernism')]
# [('p', 'http://www.wikidata.org/entity/Q1133329'), ('name', 'Young Poland')]
# [('p', 'http://www.wikidata.org/entity/Q979160'), ('name', 'Proto-Renaissance')]
# [('p', 'http://www.wikidata.org/entity/Q1172762'), ('name', 'Dau al Set')]
# [('p', 'http://www.wikidata.org/entity/Q2907232'), ('name', 'Antropophagia')]
# [('p', 'http://www.wikidata.org/entity/Q4920294'), ('name', 'Black Arts Movement')]
# [('p', 'http://www.wikidata.org/entity/Q153946'), ('name', 'punk counterculture')]
# [('p', 'http://www.wikidata.org/entity/Q6110311'), ('name', 'flamenco rock')]
# [('p', 'http://www.wikidata.org/entity/Q1413061'), ('name', 'tropicália')]
# [('p', 'http://www.wikidata.org/entity/Q7215510'), ('name', 'Ukrainian Russophiles')]
# [('p', 'http://www.wikidata.org/entity/Q2368408'), ('name', 'artistic indianism')]
# [('p', 'http://www.wikidata.org/entity/Q703472'), ('name', 'Renaixença')]
# [('p', 'http://www.wikidata.org/entity/Q16497571'), ('name', 'Brazilian Belle Époque')]
# [('p', 'http://www.wikidata.org/entity/Q1745141'), ('name', 'Fantastic Realism')]
# [('p', 'http://www.wikidata.org/entity/Q61693382'), ('name', 'pilantragem')]
# [('p', 'http://www.wikidata.org/entity/Q852377'), ('name', 'New Culture Movement')]
# [('p', 'http://www.wikidata.org/entity/Q63442026'), ('name', 'High Baroque')]
# [('p', 'http://www.wikidata.org/entity/Q899271'), ('name', 'Baroque in Brazil')]
# [('p', 'http://www.wikidata.org/entity/Q4922353'), ('name', 'Black is Beautiful')]
# [('p', 'http://www.wikidata.org/entity/Q1431758'), ('name', 'San Francisco Renaissance')]
# [('p', 'http://www.wikidata.org/entity/Q1520921'), ('name', 'Nahda')]
# [('p', 'http://www.wikidata.org/entity/Q2289148'), ('name', 'The Singing Voice of Germany')]
# [('p', 'http://www.wikidata.org/entity/Q877637'), ('name', 'Rangaku')]
# [('p', 'http://www.wikidata.org/entity/Q3683985'), ('name', 'combat folk')]
# [('p', 'http://www.wikidata.org/entity/Q234105'), ('name', 'Lost Generation')]
# [('p', 'http://www.wikidata.org/entity/Q5651123'), ('name', 'Hanshinkan Modernism')]
# [('p', 'http://www.wikidata.org/entity/Q57206373'), ('name', 'Black Aesthetic')]
# [('p', 'http://www.wikidata.org/entity/Q1713406'), ('name', 'Young Germany')]
# [('p', 'http://www.wikidata.org/entity/Q700923'), ('name', 'Vormärz')]
# [('p', 'http://www.wikidata.org/entity/Q3326886'), ('name', 'Ez Dok Amairu')]
# [('p', 'http://www.wikidata.org/entity/Q2037910'), ('name', 'Swinging London')]
# [('p', 'http://www.wikidata.org/entity/Q8059379'), ('name', 'Youthquake')]
# [('p', 'http://www.wikidata.org/entity/Q74950'), ('name', 'objectivism')]
# [('p', 'http://www.wikidata.org/entity/Q856643'), ('name', 'Trecento')]
# [('p', 'http://www.wikidata.org/entity/Q105661166'), ('name', 'Tutmania')]
# [('p', 'http://www.wikidata.org/entity/Q254272'), ('name', 'Egyptomania')]
# [('p', 'http://www.wikidata.org/entity/Q700324'), ('name', 'Bunmei Kaika')]
# [('p', 'http://www.wikidata.org/entity/Q1334000'), ('name', 'School of Salamanca')]
# [('p', 'http://www.wikidata.org/entity/Q3307647'), ('name', 'Rexurdimento')]
# [('p', 'http://www.wikidata.org/entity/Q104215395'), ('name', 'Africanfuturism')]
# [('p', 'http://www.wikidata.org/entity/Q3953335'), ('name', 'Genoa school')]
# [('p', 'http://www.wikidata.org/entity/Q6025377'), ('name', 'Movimiento indaliano')]
# [('p', 'http://www.wikidata.org/entity/Q3759612'), ('name', 'Generation of 1914')]
# [('p', 'http://www.wikidata.org/entity/Q695274'), ('name', 'Philhellenism')]
# 100

# %%
# BGP OF BAROQUE AND RENAISSANCE AND ROMANTICISM
#[('p', 'http://www.wikidata.org/entity/Q37853'), ('name', 'Baroque')
#[('p', 'http://www.wikidata.org/entity/Q1472236'), ('name', 'Early Renaissance')]
#[('p', 'http://www.wikidata.org/entity/Q4692'), ('name', 'Renaissance'),
#[('p', 'http://www.wikidata.org/entity/Q37068'), ('name', 'Romanticism')]


queryString = """
SELECT DISTINCT ?p ?name ?o ?nm ?p1 ?name1
WHERE{ {
   # bind something
    wd:Q37853 ?p ?o.
   # get the label
   # ?p sc:name ?name.   
}
Union
{
# bind something
    wd:Q4692 ?p1 ?o.
   # get the label
   # ?p1 sc:name ?name1.
   }
   Union
{
# bind something
    wd:Q37068 ?x ?o.
   # get the label
   # ?x sc:name ?nm.
   }
   }
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P1014'), ('name', 'Art & Architecture Thesaurus ID'), ('o', '300021147')]
# [('p', 'http://www.wikidata.org/prop/direct/P1051'), ('name', 'PSH ID'), ('o', '11644')]
# [('p', 'http://www.wikidata.org/prop/direct/P1245'), ('name', 'OmegaWiki Defined Meaning'), ('o', '687754')]
# [('p', 'http://www.wikidata.org/prop/direct/P1296'), ('name', 'Gran Enciclopèdia Catalana ID'), ('o', '0162729')]
# [('p', 'http://www.wikidata.org/prop/direct/P1296'), ('name', 'Gran Enciclopèdia Catalana ID'), ('o', '0007955')]
# [('p', 'http://www.wikidata.org/prop/direct/P1296'), ('name', 'Gran Enciclopèdia Catalana ID'), ('o', '0083458')]
# [('p', 'http://www.wikidata.org/prop/direct/P1343'), ('name', 'described by source'), ('o', 'http://www.wikidata.org/entity/Q2041543')]
# [('p', 'http://www.wikidata.org/prop/direct/P1343'), ('name', 'described by source'), ('o', 'http://www.wikidata.org/entity/Q2657718')]
# [('p', 'http://www.wikidata.org/prop/direct/P1343'), ('name', 'described by source'), ('o', 'http://www.wikidata.org/entity/Q3181656')]
# [('p', 'http://www.wikidata.org/prop/direct/P1417'), ('name', 'Encyclopædia Britannica Online ID'), ('o', 'art/Baroque-art-and-architecture')]
# [('p', 'http://www.wikidata.org/prop/direct/P1417'), ('name', 'Encyclopædia Britannica Online ID'), ('o', 'art/Baroque-period')]
# [('p', 'http://www.wikidata.org/prop/direct/P155'), ('name', 'follows'), ('o', 'http://www.wikidata.org/entity/Q131808')]
# [('p', 'http://www.wikidata.org/prop/direct/P155'), ('name', 'follows'), ('o', 'http://www.wikidata.org/entity/Q4692')]
# [('p', 'http://www.wikidata.org/prop/direct/P18'), ('name', 'image'), ('o', 'http://commons.wikimedia.org/wiki/Special:FilePath/Lazio%20Roma%20SIgnazio%20tango7174.jpg')]
# [('p', 'http://www.wikidata.org/prop/direct/P1807'), ('name', 'Great Aragonese Encyclopedia ID'), ('o', '1993')]
# [('p', 'http://www.wikidata.org/prop/direct/P227'), ('name', 'GND ID'), ('o', '4004541-9')]
# [('p', 'http://www.wikidata.org/prop/direct/P2347'), ('name', 'YSO ID'), ('o', '15757')]
# [('p', 'http://www.wikidata.org/prop/direct/P244'), ('name', 'Library of Congress authority ID'), ('o', 'sh85008345')]
# [('p', 'http://www.wikidata.org/prop/direct/P2581'), ('name', 'BabelNet ID'), ('o', '00008669n')]
# [('p', 'http://www.wikidata.org/prop/direct/P268'), ('name', 'Bibliothèque nationale de France ID'), ('o', '11948397n')]
# [('p', 'http://www.wikidata.org/prop/direct/P2924'), ('name', 'Great Russian Encyclopedia Online ID'), ('o', '1862794')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('name', 'instance of'), ('o', 'http://www.wikidata.org/entity/Q11514315')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('name', 'instance of'), ('o', 'http://www.wikidata.org/entity/Q1292119')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('name', 'instance of'), ('o', 'http://www.wikidata.org/entity/Q32880')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('name', 'instance of'), ('o', 'http://www.wikidata.org/entity/Q968159')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('name', 'instance of'), ('o', 'http://www.wikidata.org/entity/Q2198855')]
# [('p', 'http://www.wikidata.org/prop/direct/P3219'), ('name', 'Encyclopædia Universalis ID'), ('o', 'baroque')]
# [('p', 'http://www.wikidata.org/prop/direct/P3241'), ('name', 'Catholic Encyclopedia ID'), ('o', '02303b')]
# [('p', 'http://www.wikidata.org/prop/direct/P3365'), ('name', 'Treccani ID'), ('o', 'barocco')]
# [('p', 'http://www.wikidata.org/prop/direct/P3417'), ('name', 'Quora topic ID'), ('o', 'Barroco')]
# [('p', 'http://www.wikidata.org/prop/direct/P3569'), ('name', 'Cultureel Woordenboek ID'), ('o', 'kunst-van-renaissance-tot-1850/barok')]
# [('p', 'http://www.wikidata.org/prop/direct/P373'), ('name', 'Commons category'), ('o', 'Baroque art')]
# [('p', 'http://www.wikidata.org/prop/direct/P3827'), ('name', 'JSTOR topic ID'), ('o', 'baroque-art')]
# [('p', 'http://www.wikidata.org/prop/direct/P3827'), ('name', 'JSTOR topic ID'), ('o', 'baroque-literature')]
# [('p', 'http://www.wikidata.org/prop/direct/P5019'), ('name', 'Brockhaus Enzyklopädie online ID'), ('o', 'barock')]
# [('p', 'http://www.wikidata.org/prop/direct/P5063'), ('name', 'Interlingual Index ID'), ('o', 'i117432')]
# [('p', 'http://www.wikidata.org/prop/direct/P508'), ('name', 'BNCF Thesaurus ID'), ('o', '18806')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('name', 'has part'), ('o', 'http://www.wikidata.org/entity/Q1431376')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('name', 'has part'), ('o', 'http://www.wikidata.org/entity/Q3624106')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('name', 'has part'), ('o', 'http://www.wikidata.org/entity/Q63442026')]
# [('p', 'http://www.wikidata.org/prop/direct/P5604'), ('name', 'archINFORM keyword ID'), ('o', '111')]
# [('p', 'http://www.wikidata.org/prop/direct/P580'), ('name', 'start time'), ('o', '1590-01-01T00:00:00Z')]
# [('p', 'http://www.wikidata.org/prop/direct/P582'), ('name', 'end time'), ('o', '1750-01-01T00:00:00Z')]
# [('p', 'http://www.wikidata.org/prop/direct/P6058'), ('name', 'Larousse ID'), ('o', 'divers/wd/25737')]
# [('p', 'http://www.wikidata.org/prop/direct/P6366'), ('name', 'Microsoft Academic ID'), ('o', '136410877')]
# [('p', 'http://www.wikidata.org/prop/direct/P6404'), ('name', "Treccani's Dizionario di Storia ID"), ('o', 'barocco')]
# [('p', 'http://www.wikidata.org/prop/direct/P6412'), ('name', 'Gran Enciclopèdia de la Música ID'), ('o', '2413')]
# [('p', 'http://www.wikidata.org/prop/direct/P646'), ('name', 'Freebase ID'), ('o', '/m/0194x')]
# [('p', 'http://www.wikidata.org/prop/direct/P6573'), ('name', 'Klexikon article ID'), ('o', 'Barock')]
# [('p', 'http://www.wikidata.org/prop/direct/P737'), ('name', 'influenced by'), ('o', 'http://www.wikidata.org/entity/Q172991')]
# [('p', 'http://www.wikidata.org/prop/direct/P7786'), ('name', 'Joconde epoch ID'), ('o', 'T93-913')]
# [('p', 'http://www.wikidata.org/prop/direct/P7818'), ('name', 'French Vikidia ID'), ('o', 'Art_baroque')]
# [('p', 'http://www.wikidata.org/prop/direct/P7827'), ('name', 'Spanish Vikidia ID'), ('o', 'Barroco')]
# [('p', 'http://www.wikidata.org/prop/direct/P7982'), ('name', 'Hrvatska enciklopedija ID'), ('o', '6003')]
# [('p', 'http://www.wikidata.org/prop/direct/P8135'), ('name', 'Encyclopedia of České Budějovice ID'), ('o', 'baroko')]
# [('p', 'http://www.wikidata.org/prop/direct/P8349'), ('name', 'Proleksis enciklopedija ID'), ('o', '10898')]
# [('p', 'http://www.wikidata.org/prop/direct/P8406'), ('name', 'Grove Art Online ID'), ('o', 'T006459')]
# [('p', 'http://www.wikidata.org/prop/direct/P8432'), ('name', 'Österreichisches Musiklexikon Online ID'), ('o', 'B/Barock')]
# [('p', 'http://www.wikidata.org/prop/direct/P8519'), ('name', 'RKD thesaurus ID'), ('o', '65181')]
# [('p', 'http://www.wikidata.org/prop/direct/P8814'), ('name', 'WordNet 3.1 Synset ID'), ('o', '15283887-n')]
# [('p', 'http://www.wikidata.org/prop/direct/P902'), ('name', 'HDS ID'), ('o', '011182')]
# [('p', 'http://www.wikidata.org/prop/direct/P910'), ('name', "topic's main category"), ('o', 'http://www.wikidata.org/entity/Q8810374')]
# [('p', 'http://www.wikidata.org/prop/direct/P920'), ('name', 'LEM ID'), ('o', 'LEM201009649')]
# [('p', 'http://www.wikidata.org/prop/direct/P950'), ('name', 'Biblioteca Nacional de España ID'), ('o', 'XX525325')]
# [('p', 'http://www.wikidata.org/prop/direct/P989'), ('name', 'spoken text audio'), ('o', 'http://commons.wikimedia.org/wiki/Special:FilePath/Baroko%20-%20namluven%C3%BD%20%C4%8Dl%C3%A1nek.ogg')]
# [('p', 'http://www.wikidata.org/prop/direct/P9779'), ('name', 'abART term ID'), ('o', '2033')]
# [('o', '300021140'), ('p1', 'http://www.wikidata.org/prop/direct/P1014'), ('name1', 'Art & Architecture Thesaurus ID')]
# [('o', '11642'), ('p1', 'http://www.wikidata.org/prop/direct/P1051'), ('name1', 'PSH ID')]
# [('o', 'http://www.wikidata.org/entity/Q13830551'), ('p1', 'http://www.wikidata.org/prop/direct/P1151'), ('name1', "topic's main Wikimedia portal")]
# [('o', '23T26'), ('p1', 'http://www.wikidata.org/prop/direct/P1256'), ('name1', 'Iconclass notation')]
# [('o', 'http://www.wikidata.org/entity/Q2041543'), ('p1', 'http://www.wikidata.org/prop/direct/P1343'), ('name1', 'described by source')]
# [('o', 'http://www.wikidata.org/entity/Q3181656'), ('p1', 'http://www.wikidata.org/prop/direct/P1343'), ('name1', 'described by source')]
# [('o', 'http://www.wikidata.org/entity/Q602358'), ('p1', 'http://www.wikidata.org/prop/direct/P1343'), ('name1', 'described by source')]
# [('o', 'event/Renaissance'), ('p1', 'http://www.wikidata.org/prop/direct/P1417'), ('name1', 'Encyclopædia Britannica Online ID')]
# [('o', 'http://www.wikidata.org/entity/Q10999203'), ('p1', 'http://www.wikidata.org/prop/direct/P1424'), ('name1', "topic's main template")]
# [('o', 'http://www.wikidata.org/entity/Q12554'), ('p1', 'http://www.wikidata.org/prop/direct/P155'), ('name1', 'follows')]
# [('o', 'http://www.wikidata.org/entity/Q46825'), ('p1', 'http://www.wikidata.org/prop/direct/P155'), ('name1', 'follows')]
# [('o', 'http://www.wikidata.org/entity/Q37853'), ('p1', 'http://www.wikidata.org/prop/direct/P156'), ('name1', 'followed by')]
# [('o', 'http://commons.wikimedia.org/wiki/Special:FilePath/Da%20Vinci%20Vitruve%20Luc%20Viatour.jpg'), ('p1', 'http://www.wikidata.org/prop/direct/P18'), ('name1', 'image')]
# [('o', 'http://commons.wikimedia.org/wiki/Special:FilePath/%27David%27%20by%20Michelangelo%20JBU04.JPG'), ('p1', 'http://www.wikidata.org/prop/direct/P18'), ('name1', 'image')]
# [('o', 'http://commons.wikimedia.org/wiki/Special:FilePath/Sandro%20Botticelli%20-%20La%20nascita%20di%20Venere%20-%20Google%20Art%20Project.jpg'), ('p1', 'http://www.wikidata.org/prop/direct/P18'), ('name1', 'image')]
# [('o', '10762'), ('p1', 'http://www.wikidata.org/prop/direct/P1807'), ('name1', 'Great Aragonese Encyclopedia ID')]
# [('o', 'http://www.wikidata.org/entity/Q13400700'), ('p1', 'http://www.wikidata.org/prop/direct/P1889'), ('name1', 'different from')]
# [('o', '4049450-0'), ('p1', 'http://www.wikidata.org/prop/direct/P227'), ('name1', 'GND ID')]
# [('o', '4979'), ('p1', 'http://www.wikidata.org/prop/direct/P2347'), ('name1', 'YSO ID')]
# [('o', 'sh85112806'), ('p1', 'http://www.wikidata.org/prop/direct/P244'), ('name1', 'Library of Congress authority ID')]
# [('o', 'http://www.wikidata.org/entity/Q25111456'), ('p1', 'http://www.wikidata.org/prop/direct/P2579'), ('name1', 'studied by')]
# [('o', '13318531w'), ('p1', 'http://www.wikidata.org/prop/direct/P268'), ('name1', 'Bibliothèque nationale de France ID')]
# [('o', 'http://www.wikidata.org/entity/Q27496'), ('p1', 'http://www.wikidata.org/prop/direct/P276'), ('name1', 'location')]
# [('o', '1924973'), ('p1', 'http://www.wikidata.org/prop/direct/P2924'), ('name1', 'Great Russian Encyclopedia Online ID')]
# [('o', 'http://www.wikidata.org/entity/Q32880'), ('p1', 'http://www.wikidata.org/prop/direct/P31'), ('name1', 'instance of')]
# [('o', 'http://www.wikidata.org/entity/Q968159'), ('p1', 'http://www.wikidata.org/prop/direct/P31'), ('name1', 'instance of')]
# [('o', 'http://www.wikidata.org/entity/Q2198855'), ('p1', 'http://www.wikidata.org/prop/direct/P31'), ('name1', 'instance of')]
# [('o', 'renässans'), ('p1', 'http://www.wikidata.org/prop/direct/P3222'), ('name1', 'NE.se ID')]
# [('o', '12765b'), ('p1', 'http://www.wikidata.org/prop/direct/P3241'), ('name1', 'Catholic Encyclopedia ID')]
# [('o', 'The-Renacimiento'), ('p1', 'http://www.wikidata.org/prop/direct/P3417'), ('name1', 'Quora topic ID')]
# [('o', '00569811'), ('p1', 'http://www.wikidata.org/prop/direct/P349'), ('name1', 'National Diet Library ID')]
# [('o', '19597086'), ('p1', 'http://www.wikidata.org/prop/direct/P3553'), ('name1', 'Zhihu topic ID')]
# [('o', 'Renaissance'), ('p1', 'http://www.wikidata.org/prop/direct/P373'), ('name1', 'Commons category')]
# [('o', 'renaissance'), ('p1', 'http://www.wikidata.org/prop/direct/P3827'), ('name1', 'JSTOR topic ID')]
# 100

# %% [markdown]
# ## Task 3
# Identify the BGP for composer, painter, sculptor and poet

# %%
# write your queries
queryString = """
SELECT DISTINCT ?p ?name
WHERE {
   # bind something
   wd:Q37562 ?obj ?p .
   # get the label
   # ?p sc:name ?name.
   
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/entity/Q1028181'), ('name', 'painter')]
# [('p', 'http://www.wikidata.org/entity/Q104694359'), ('name', 'WikiProject PCC Wikidata Pilot/Frick Art Reference Library')]
# [('p', 'http://www.wikidata.org/entity/Q106675203'), ('name', 'WikiProject PCC Wikidata Pilot/Berenson Library')]
# [('p', 'http://www.wikidata.org/entity/Q1081881'), ('name', 'National Museum of San Matteo')]
# [('p', 'http://www.wikidata.org/entity/Q1281618'), ('name', 'sculptor')]
# [('p', 'http://www.wikidata.org/entity/Q13362'), ('name', 'Ferrara')]
# [('p', 'http://www.wikidata.org/entity/Q13375'), ('name', 'Pisa')]
# [('p', 'http://www.wikidata.org/entity/Q134307'), ('name', 'portrait')]
# [('p', 'http://www.wikidata.org/entity/Q1472236'), ('name', 'Early Renaissance')]
# [('p', 'http://www.wikidata.org/entity/Q148540'), ('name', 'Republic of Florence')]
# [('p', 'http://www.wikidata.org/entity/Q180788'), ('name', 'National Gallery')]
# [('p', 'http://www.wikidata.org/entity/Q2044'), ('name', 'Florence')]
# [('p', 'http://www.wikidata.org/entity/Q213322'), ('name', 'Victoria and Albert Museum')]
# [('p', 'http://www.wikidata.org/entity/Q214867'), ('name', 'National Gallery of Art')]
# [('p', 'http://www.wikidata.org/entity/Q220'), ('name', 'Rome')]
# [('p', 'http://www.wikidata.org/entity/Q2634'), ('name', 'Naples')]
# [('p', 'http://www.wikidata.org/entity/Q2751'), ('name', 'Siena')]
# [('p', 'http://www.wikidata.org/entity/Q2864737'), ('name', 'religious art')]
# [('p', 'http://www.wikidata.org/entity/Q3181656'), ('name', 'The Nuttall Encyclopædia')]
# [('p', 'http://www.wikidata.org/entity/Q3374376'), ('name', 'mythological painting')]
# [('p', 'http://www.wikidata.org/entity/Q483501'), ('name', 'artist')]
# [('p', 'http://www.wikidata.org/entity/Q49133'), ('name', 'Museum of Fine Arts')]
# [('p', 'http://www.wikidata.org/entity/Q5'), ('name', 'human')]
# [('p', 'http://www.wikidata.org/entity/Q50001'), ('name', 'Italians')]
# [('p', 'http://www.wikidata.org/entity/Q5503390'), ('name', 'Frick Art Reference Library')]
# [('p', 'http://www.wikidata.org/entity/Q59452059'), ('name', 'Berenson Library')]
# [('p', 'http://www.wikidata.org/entity/Q602358'), ('name', 'Brockhaus and Efron Encyclopedic Dictionary')]
# [('p', 'http://www.wikidata.org/entity/Q6247'), ('name', 'Mantua')]
# [('p', 'http://www.wikidata.org/entity/Q652'), ('name', 'Italian')]
# [('p', 'http://www.wikidata.org/entity/Q6581097'), ('name', 'male')]
# [('p', 'http://www.wikidata.org/entity/Q67311526'), ('name', 'Obalky knih.cz')]
# [('p', 'http://www.wikidata.org/entity/Q679527'), ('name', 'Museum Boijmans Van Beuningen')]
# [('p', 'http://www.wikidata.org/entity/Q71887839'), ('name', 'copyrights on works have expired')]
# [('p', 'http://www.wikidata.org/entity/Q842858'), ('name', 'Nationalmuseum')]
# [('p', 'http://www.wikidata.org/entity/Q856749'), ('name', 'Bicci di Lorenzo')]
# [('p', 'http://www.wikidata.org/entity/Q11634'), ('name', 'art of sculpture')]
# [('p', 'http://www.wikidata.org/entity/Q1165526'), ('name', 'Musée Jacquemart-André')]
# [('p', 'http://www.wikidata.org/entity/Q1200696'), ('name', "Museo dell'Opera del Duomo")]
# [('p', 'http://www.wikidata.org/entity/Q13373'), ('name', 'Lucca')]
# [('p', 'http://www.wikidata.org/entity/Q13377'), ('name', 'Prato')]
# [('p', 'http://www.wikidata.org/entity/Q157825'), ('name', 'Bode Museum')]
# [('p', 'http://www.wikidata.org/entity/Q1636061'), ('name', 'Zuccone')]
# [('p', 'http://www.wikidata.org/entity/Q191739'), ('name', 'Florence Cathedral')]
# [('p', 'http://www.wikidata.org/entity/Q19967495'), ('name', 'Donatello')]
# [('p', 'http://www.wikidata.org/entity/Q271928'), ('name', 'Palazzo Vecchio')]
# [('p', 'http://www.wikidata.org/entity/Q279'), ('name', 'Modena')]
# [('p', 'http://www.wikidata.org/entity/Q3330090'), ('name', 'Villa Guinigi National Museum')]
# [('p', 'http://www.wikidata.org/entity/Q3399515'), ('name', 'equestrian portrait')]
# [('p', 'http://www.wikidata.org/entity/Q3698261'), ('name', 'Crucifix in Santa Croce')]
# [('p', 'http://www.wikidata.org/entity/Q3867573'), ('name', 'Museum Bardini')]
# [('p', 'http://www.wikidata.org/entity/Q388448'), ('name', 'Bargello')]
# [('p', 'http://www.wikidata.org/entity/Q395755'), ('name', 'Agostino di Duccio')]
# [('p', 'http://www.wikidata.org/entity/Q51177'), ('name', 'Basilica of Santa Croce')]
# [('p', 'http://www.wikidata.org/entity/Q573881'), ('name', 'Basilica of San Lorenzo')]
# [('p', 'http://www.wikidata.org/entity/Q617'), ('name', 'Padua')]
# [('p', 'http://www.wikidata.org/entity/Q628471'), ('name', 'Donato')]
# [('p', 'http://www.wikidata.org/entity/Q640232'), ('name', 'Tomb of Giovanni Pecci')]
# [('p', 'http://www.wikidata.org/entity/Q64214265'), ('name', 'Wiki Loves Pride Art & Artists')]
# [('p', 'http://www.wikidata.org/entity/Q651579'), ('name', 'Handel holding Putti in the museum Jacquemart-André')]
# [('p', 'http://www.wikidata.org/entity/Q66087835'), ('name', 'Donatello')]
# [('p', 'http://www.wikidata.org/entity/Q735085'), ('name', 'David')]
# [('p', 'http://www.wikidata.org/entity/Q79320565'), ('name', 'Donatello')]
# [('p', 'http://www.wikidata.org/entity/Q828363'), ('name', 'Bertoldo di Giovanni')]
# [('p', 'http://www.wikidata.org/entity/Q9141126'), ('name', 'Category:Donatello')]
# [('p', 'http://www.wikidata.org/entity/Q98688625'), ('name', 'di Niccolò di Betto Bardi')]
# [('p', 'http://www.wikidata.org/entity/Q99357626'), ('name', 'Book Donatello by Arsène Alexandre')]
# 66

# %%
#Including the 2 Numbers from last result (Painter and Scupltor)
#[('p', 'http://www.wikidata.org/entity/Q1028181'), ('name', 'painter')]
#[('p', 'http://www.wikidata.org/entity/Q1281618'), ('name', 'sculptor')]
# write your queries
queryString = """
SELECT DISTINCT ?p ?name
WHERE {
   # bind something
   wd:Q1028181 ?obj ?p .
   # get the label
   # ?p sc:name ?name.
   
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/entity/Q1027879'), ('name', 'graphics')]
# [('p', 'http://www.wikidata.org/entity/Q128538'), ('name', 'Luke the Evangelist')]
# [('p', 'http://www.wikidata.org/entity/Q5914426'), ('name', 'Template:Infobox artist')]
# [('p', 'http://www.wikidata.org/entity/Q6615720'), ('name', 'Category:Painters')]
# [('p', 'http://www.wikidata.org/entity/Q11629'), ('name', 'art of painting')]
# [('p', 'http://www.wikidata.org/entity/Q12737077'), ('name', 'occupation')]
# [('p', 'http://www.wikidata.org/entity/Q174705'), ('name', 'oil painting')]
# [('p', 'http://www.wikidata.org/entity/Q28640'), ('name', 'profession')]
# [('p', 'http://www.wikidata.org/entity/Q174219'), ('name', 'paint')]
# [('p', 'http://www.wikidata.org/entity/Q189085'), ('name', 'pastel')]
# [('p', 'http://www.wikidata.org/entity/Q3391743'), ('name', 'visual artist')]
# [('p', 'http://www.wikidata.org/entity/Q193897'), ('name', 'paintbrush')]
# [('p', 'http://www.wikidata.org/entity/Q3300034'), ('name', 'painting material')]
# [('p', 'http://www.wikidata.org/entity/Q861259'), ('name', 'painting surface')]
# [('p', 'http://www.wikidata.org/entity/Q425548'), ('name', 'palette')]
# [('p', 'http://www.wikidata.org/entity/Q939611'), ('name', 'easel')]
# [('p', 'http://www.wikidata.org/entity/P4687'), ('name', 'Dictionnaire des peintres belges ID')]
# [('p', 'http://www.wikidata.org/entity/Q1375139'), ('name', 'Malíř')]
# [('p', 'http://www.wikidata.org/entity/Q8538537'), ('name', 'Category:Wikipedia categories named after painters')]
# 19

# %%
#exploring occupation for composer and poet
#[('p', 'http://www.wikidata.org/entity/Q12737077'), ('name', 'occupation')]
queryString = """
SELECT DISTINCT ?p ?name
WHERE {
   # bind something
   wd:Q12737077 ?obj ?p .
   # get the label
   # ?p sc:name ?name.
   
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/entity/Q4048530'), ('name', 'Category:Occupations')]
# [('p', 'http://www.wikidata.org/entity/Q151885'), ('name', 'concept')]
# [('p', 'http://www.wikidata.org/entity/Q28640'), ('name', 'profession')]
# [('p', 'http://www.wikidata.org/entity/Q4164871'), ('name', 'position')]
# [('p', 'http://www.wikidata.org/entity/Q24017414'), ('name', 'second-order class')]
# [('p', 'http://www.wikidata.org/entity/Q1807498'), ('name', 'social position')]
# [('p', 'http://www.wikidata.org/entity/P106'), ('name', 'occupation')]
# [('p', 'http://www.wikidata.org/entity/P3095'), ('name', 'practiced by')]
# [('p', 'http://www.wikidata.org/entity/P425'), ('name', 'field of this occupation')]
# 9

# %%
#exploring occupation for composer and poet
#[('p', 'http://www.wikidata.org/entity/P106'), ('name', 'occupation')]queryString = """
queryString = """
SELECT DISTINCT ?p ?name
WHERE {
   # bind something
    # ?obj wdt:P106 ?p .
   # get the label
   # ?p sc:name ?name.
   filter(regex(?name,"Composer"))
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/entity/Q15252222'), ('name', 'Composer')]
# [('p', 'http://www.wikidata.org/entity/Q16387857'), ('name', 'Composers Union of Armenia')]
# [('p', 'http://www.wikidata.org/entity/Q8008937'), ('name', 'Category:Composers')]
# [('p', 'http://www.wikidata.org/entity/Q1754714'), ('name', 'Media Composer')]
# [('p', 'http://www.wikidata.org/entity/Q1121767'), ('name', 'Composer')]
# 5

# %%
#exploring occupation for composer and poet
#[('p', 'http://www.wikidata.org/entity/P106'), ('name', 'occupation')]queryString = """
queryString = """
SELECT DISTINCT ?p ?name
WHERE {
   # bind something
    # ?obj wdt:P106 ?p .
   # get the label
   # ?p sc:name ?name.
   filter(regex(?name,"poet"))
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/entity/Q106376813'), ('name', 'visual poet')]
# [('p', 'http://www.wikidata.org/entity/Q1209498'), ('name', 'poet lawyer')]
# [('p', 'http://www.wikidata.org/entity/Q482'), ('name', 'poetry')]
# [('p', 'http://www.wikidata.org/entity/Q49757'), ('name', 'poet')]
# [('p', 'http://www.wikidata.org/entity/Q182357'), ('name', 'lyric poetry')]
# [('p', 'http://www.wikidata.org/entity/Q11386386'), ('name', 'haiku poet')]
# [('p', 'http://www.wikidata.org/entity/Q11122954'), ('name', 'tanka poet')]
# [('p', 'http://www.wikidata.org/entity/Q23117687'), ('name', 'dithyrambic poet')]
# [('p', 'http://www.wikidata.org/entity/Q1237928'), ('name', 'poet laureate')]
# [('p', 'http://www.wikidata.org/entity/Q2293636'), ('name', 'slam poet')]
# [('p', 'http://www.wikidata.org/entity/Q7168247'), ('name', 'performance poetry')]
# [('p', 'http://www.wikidata.org/entity/Q7207537'), ('name', 'poetry reading')]
# [('p', 'http://www.wikidata.org/entity/Q107714046'), ('name', 'performance poet')]
# [('p', 'http://www.wikidata.org/entity/Q107230508'), ('name', 'woman poet')]
# [('p', 'http://www.wikidata.org/entity/Q17378131'), ('name', 'dub poet')]
# [('p', 'http://www.wikidata.org/entity/Q104824215'), ('name', 'poetry teacher')]
# [('p', 'http://www.wikidata.org/entity/Q12901590'), ('name', 'poetaster')]
# [('p', 'http://www.wikidata.org/entity/Q2293670'), ('name', 'slam poetry')]
# [('p', 'http://www.wikidata.org/entity/Q3401082'), ('name', 'war poet')]
# [('p', 'http://www.wikidata.org/entity/Q20528752'), ('name', 'concrete poet')]
# [('p', 'http://www.wikidata.org/entity/Q73644030'), ('name', 'urdu poets')]
# [('p', 'http://www.wikidata.org/entity/Q104236711'), ('name', 'modern poetry scholar')]
# 22

# %% [markdown]
# Final query for this task

# %%
#[('p', 'http://www.wikidata.org/entity/Q49757'), ('name', 'poet')]
#[('p', 'http://www.wikidata.org/entity/Q1121767'), ('name', 'Composer')]
#[('p', 'http://www.wikidata.org/entity/Q1028181'), ('name', 'painter')]
#[('p', 'http://www.wikidata.org/entity/Q1281618'), ('name', 'sculptor')]
queryString = """
SELECT DISTINCT ?p ?name ?o ?nm ?p1 ?name1 ?nmm ?u
WHERE{ {
   # bind something
    wd:Q49757 ?p ?o.
   # get the label
   # ?p sc:name ?name.   
}
Union
{
# bind something
    wd:Q1121767 ?p1 ?o.
   # get the label
   # ?p1 sc:name ?name1.
   }
   Union
{
# bind something
    wd:Q1028181 ?x ?o.
   # get the label
   # ?x sc:name ?nm.
   }
   
   Union
{
# bind something
    wd:Q1281618 ?u ?z.
   # get the label
   # ?u sc:name ?nmm.
   }
   }
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P1014'), ('name', 'Art & Architecture Thesaurus ID'), ('o', '300025513')]
# [('p', 'http://www.wikidata.org/prop/direct/P1296'), ('name', 'Gran Enciclopèdia Catalana ID'), ('o', '0133026')]
# [('p', 'http://www.wikidata.org/prop/direct/P1343'), ('name', 'described by source'), ('o', 'http://www.wikidata.org/entity/Q106727050')]
# [('p', 'http://www.wikidata.org/prop/direct/P1709'), ('name', 'equivalent class'), ('o', 'http://dbpedia.org/ontology/Poet')]
# [('p', 'http://www.wikidata.org/prop/direct/P1889'), ('name', 'different from'), ('o', 'http://www.wikidata.org/entity/Q24054302')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('name', 'properties for this type'), ('o', 'http://www.wikidata.org/entity/P5509')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('name', 'properties for this type'), ('o', 'http://www.wikidata.org/entity/P5477')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('name', 'properties for this type'), ('o', 'http://www.wikidata.org/entity/P5506')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('name', 'properties for this type'), ('o', 'http://www.wikidata.org/entity/P5710')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('name', 'properties for this type'), ('o', 'http://www.wikidata.org/entity/P5430')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('name', 'properties for this type'), ('o', 'http://www.wikidata.org/entity/P5343')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('name', 'properties for this type'), ('o', 'http://www.wikidata.org/entity/P5609')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('name', 'properties for this type'), ('o', 'http://www.wikidata.org/entity/P5503')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('name', 'properties for this type'), ('o', 'http://www.wikidata.org/entity/P5344')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('name', 'properties for this type'), ('o', 'http://www.wikidata.org/entity/P5393')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('name', 'properties for this type'), ('o', 'http://www.wikidata.org/entity/P5394')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('name', 'properties for this type'), ('o', 'http://www.wikidata.org/entity/P5465')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('name', 'properties for this type'), ('o', 'http://www.wikidata.org/entity/P5341')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('name', 'properties for this type'), ('o', 'http://www.wikidata.org/entity/P5392')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('name', 'properties for this type'), ('o', 'http://www.wikidata.org/entity/P5470')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('name', 'properties for this type'), ('o', 'http://www.wikidata.org/entity/P5478')]
# [('p', 'http://www.wikidata.org/prop/direct/P227'), ('name', 'GND ID'), ('o', '4436441-6')]
# [('p', 'http://www.wikidata.org/prop/direct/P227'), ('name', 'GND ID'), ('o', '4168391-2')]
# [('p', 'http://www.wikidata.org/prop/direct/P227'), ('name', 'GND ID'), ('o', '4246394-4')]
# [('p', 'http://www.wikidata.org/prop/direct/P244'), ('name', 'Library of Congress authority ID'), ('o', 'sh85103733')]
# [('p', 'http://www.wikidata.org/prop/direct/P2581'), ('name', 'BabelNet ID'), ('o', '00063196n')]
# [('p', 'http://www.wikidata.org/prop/direct/P268'), ('name', 'Bibliothèque nationale de France ID'), ('o', '11933176q')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('name', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q36180')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('name', 'instance of'), ('o', 'http://www.wikidata.org/entity/Q28640')]
# [('p', 'http://www.wikidata.org/prop/direct/P3417'), ('name', 'Quora topic ID'), ('o', 'Poets')]
# [('p', 'http://www.wikidata.org/prop/direct/P3417'), ('name', 'Quora topic ID'), ('o', 'POETESS')]
# [('p', 'http://www.wikidata.org/prop/direct/P349'), ('name', 'National Diet Library ID'), ('o', '00571341')]
# [('p', 'http://www.wikidata.org/prop/direct/P3553'), ('name', 'Zhihu topic ID'), ('o', '19567979')]
# [('p', 'http://www.wikidata.org/prop/direct/P373'), ('name', 'Commons category'), ('o', 'Poets')]
# [('p', 'http://www.wikidata.org/prop/direct/P3916'), ('name', 'UNESCO Thesaurus ID'), ('o', 'concept15267')]
# [('p', 'http://www.wikidata.org/prop/direct/P4212'), ('name', 'PACTOLS thesaurus ID'), ('o', 'pcrthaeJNwN3zK')]
# [('p', 'http://www.wikidata.org/prop/direct/P4212'), ('name', 'PACTOLS thesaurus ID'), ('o', 'pcrto2X1tJXRSS')]
# [('p', 'http://www.wikidata.org/prop/direct/P425'), ('name', 'field of this occupation'), ('o', 'http://www.wikidata.org/entity/Q482')]
# [('p', 'http://www.wikidata.org/prop/direct/P460'), ('name', 'said to be the same as'), ('o', 'http://www.wikidata.org/entity/Q1293108')]
# [('p', 'http://www.wikidata.org/prop/direct/P508'), ('name', 'BNCF Thesaurus ID'), ('o', '5113')]
# [('p', 'http://www.wikidata.org/prop/direct/P5160'), ('name', 'Thesaurus for Graphic Materials ID'), ('o', 'tgm007949')]
# [('p', 'http://www.wikidata.org/prop/direct/P6186'), ('name', 'category for eponymous categories'), ('o', 'http://www.wikidata.org/entity/Q9579555')]
# [('p', 'http://www.wikidata.org/prop/direct/P6262'), ('name', 'Fandom article ID'), ('o', 'memory-alpha:Poet')]
# [('p', 'http://www.wikidata.org/prop/direct/P646'), ('name', 'Freebase ID'), ('o', '/m/05z96')]
# [('p', 'http://www.wikidata.org/prop/direct/P7033'), ('name', 'Australian Educational Vocabulary ID'), ('o', 'scot/2049')]
# [('p', 'http://www.wikidata.org/prop/direct/P8408'), ('name', 'KBpedia ID'), ('o', 'Poet')]
# [('p', 'http://www.wikidata.org/prop/direct/P8519'), ('name', 'RKD thesaurus ID'), ('o', '64529')]
# [('p', 'http://www.wikidata.org/prop/direct/P8814'), ('name', 'WordNet 3.1 Synset ID'), ('o', '10466829-n')]
# [('p', 'http://www.wikidata.org/prop/direct/P910'), ('name', "topic's main category"), ('o', 'http://www.wikidata.org/entity/Q6487149')]
# [('p', 'http://www.wikidata.org/prop/direct/P950'), ('name', 'Biblioteca Nacional de España ID'), ('o', 'XX533423')]
# [('p', 'http://www.wikidata.org/prop/direct/P867'), ('name', 'ROME Occupation Code (v3)'), ('o', 'E1102')]
# [('o', 'http://www.wikidata.org/entity/Q4167410'), ('p1', 'http://www.wikidata.org/prop/direct/P31'), ('name1', 'instance of')]
# [('o', '300025136'), ('nm', 'Art & Architecture Thesaurus ID')]
# [('o', 'http://www.wikidata.org/entity/Q5914426'), ('nm', "topic's main template")]
# [('o', 'http://dbpedia.org/ontology/Painter'), ('nm', 'equivalent class')]
# [('o', 'http://commons.wikimedia.org/wiki/Special:FilePath/Painters%20Xingping%20town%2020090502%206089.jpg'), ('nm', 'image')]
# [('o', 'http://www.wikidata.org/entity/Q1375139'), ('nm', 'different from')]
# [('o', 'http://www.wikidata.org/entity/P4687'), ('nm', 'properties for this type')]
# [('o', '4037215-7'), ('nm', 'GND ID')]
# [('o', '4037223-6'), ('nm', 'GND ID')]
# [('o', 'http://www.wikidata.org/entity/Q174219'), ('nm', 'uses')]
# [('o', 'http://www.wikidata.org/entity/Q193897'), ('nm', 'uses')]
# [('o', 'http://www.wikidata.org/entity/Q3300034'), ('nm', 'uses')]
# [('o', 'http://www.wikidata.org/entity/Q861259'), ('nm', 'uses')]
# [('o', 'http://www.wikidata.org/entity/Q425548'), ('nm', 'uses')]
# [('o', 'http://www.wikidata.org/entity/Q939611'), ('nm', 'uses')]
# [('o', 'sh85147670'), ('nm', 'Library of Congress authority ID')]
# [('o', '11989910g'), ('nm', 'Bibliothèque nationale de France ID')]
# [('o', 'http://www.wikidata.org/entity/Q3391743'), ('nm', 'subclass of')]
# [('o', 'http://www.wikidata.org/entity/Q12737077'), ('nm', 'instance of')]
# [('o', 'http://www.wikidata.org/entity/Q28640'), ('nm', 'instance of')]
# [('o', 'Painters'), ('nm', 'Quora topic ID')]
# [('o', '00562159'), ('nm', 'National Diet Library ID')]
# [('o', 'Painters'), ('nm', 'Commons category')]
# [('o', 'painters'), ('nm', 'Open Library subject ID')]
# [('o', 'concept3099'), ('nm', 'UNESCO Thesaurus ID')]
# [('o', 'http://www.wikidata.org/entity/Q128538'), ('nm', 'patron saint')]
# [('o', 'pcrtaynDRL2SuJ'), ('nm', 'PACTOLS thesaurus ID')]
# [('o', 'http://www.wikidata.org/entity/Q1027879'), ('nm', 'field of this occupation')]
# [('o', 'http://www.wikidata.org/entity/Q11629'), ('nm', 'field of this occupation')]
# [('o', 'http://www.wikidata.org/entity/Q174705'), ('nm', 'field of this occupation')]
# [('o', 'http://www.wikidata.org/entity/Q189085'), ('nm', 'field of this occupation')]
# [('o', 'dg2015060134'), ('nm', 'Library of Congress Demographic Group Terms ID')]
# [('o', '3784'), ('nm', 'BNCF Thesaurus ID')]
# [('o', '3783'), ('nm', 'BNCF Thesaurus ID')]
# [('o', 'pittore'), ('nm', 'Treccani Vocabulary ID')]
# [('o', 'http://www.wikidata.org/entity/Q8538537'), ('nm', 'category for eponymous categories')]
# [('o', '/m/02nxqmh'), ('nm', 'Freebase ID')]
# [('o', 'Maler'), ('nm', 'Klexikon article ID')]
# [('o', 'scot/346'), ('nm', 'Australian Educational Vocabulary ID')]
# [('o', '6'), ('nm', 'RKD thesaurus ID')]
# [('o', '46436'), ('nm', 'RKD thesaurus ID')]
# [('o', '1523'), ('nm', 'AniDB tag ID')]
# [('o', '10411352-n'), ('nm', 'WordNet 3.1 Synset ID')]
# [('o', 'http://www.wikidata.org/entity/Q6615720'), ('nm', "topic's main category")]
# [('o', 'B1101'), ('nm', 'ROME Occupation Code (v3)')]
# [('o', '2651'), ('nm', 'ISCO-88 occupation code')]
# [('nmm', 'Art & Architecture Thesaurus ID'), ('u', 'http://www.wikidata.org/prop/direct/P1014')]
# [('nmm', 'product or material produced'), ('u', 'http://www.wikidata.org/prop/direct/P1056')]
# [('nmm', 'OpenStreetMap tag or key'), ('u', 'http://www.wikidata.org/prop/direct/P1282')]
# 100

# %% [markdown]
# ## Task 4
# Consider Renaissance, Baroque and Romanticism. Find how many composers, painters, sculptors and poets belong to those cultural movements (the results set must be a list of triples movement, job, #people)

# %%
# write your queries

# %% [markdown]
# Final query for this task

# %%
# write your final query

# %% [markdown]
# ## Task 5
# Find how many sculptures were made in Italy during Renaissance, Baroque, and Romanticism movements. Please consider all the sculptures and all the sculpture subtypes. (the result set must be a list of triples movement IRI, label and #sculptures).

# %%
# write your queries

# %% [markdown]
# Final query for this task

# %%
# write your final query

# %% [markdown]
# ## Task 6
# For each European country find how many poets belong to Romanticism (the result set must be a list of triples country IRI, label and #poets).

# %%
# write your queries

# %% [markdown]
# Final query for this task

# %%
# write your final query

# %% [markdown]
# ## Task 7
# Find the number of sculptures in the Louvre Museum belonging to Renaissance, Baroque, or Romanticism (return a number for each movement) (the result set must be a list of triples movement IRI, label and #sculptures).

# %%
# write your queries

# %% [markdown]
# Final query for this task

# %%
# write your final query

# %% [markdown]
# # General instructions
#
# The goal of the project is to materialize a set of **exploratory workloads** over a real-world, large-scale,  open-domain KG: [WikiData](https://www.wikidata.org/wiki/Wikidata:Main_Page)
#
# An exploratory workload  is composed by a set of queries, where each query is related to the information obtained previously.
#
# An exploratory workload starts with a usually vague, open ended question, and does not assume the person issuing the workload has a clear understanding of the data contained in the target database or its structure.
#
# Remeber that:
#
# 1. All the queries must run in the python notebook
# 2. You can use classes and properties only if you find them via a SPARQL query that must be present in the notebook
# 3. You do not delete useless queries. Keep everything that is synthatically valid
#
# ```
# ?p <http://schema.org/name> ?name .
# ```
#
#     is the BGP returning a human-readable name of a property or a class in Wikidata.

# %%
## SETUP used later

from SPARQLWrapper import SPARQLWrapper, JSON


prefixString = """
##-841f86edd2-##
PREFIX wd: <http://www.wikidata.org/entity/> 
PREFIX wdt: <http://www.wikidata.org/prop/direct/> 
PREFIX sc: <http://schema.org/>
"""

# select and construct queries
def run_query(queryString,verbose = True):
    to_run = prefixString + "\n" + queryString

    sparql = SPARQLWrapper("http://a256-gc1-03.srv.aau.dk:5820/sparql")
    sparql.setTimeout(300)
    sparql.setReturnFormat(JSON)
    sparql.setQuery(to_run)

    try :
        results = sparql.query()
        json_results = results.convert()
        if len(json_results['results']['bindings'])==0:
            print("Empty")
            return []
        array = []
        for bindings in json_results['results']['bindings']:
            app =  [ (var, value['value'])  for var, value in bindings.items() ] 
            if verbose:
                print( app)
            array.append(app)
        if verbose:
            print(len(array))
        return array

    except Exception as e :
        print("The operation failed", e)
    
# ASk queries
def run_ask_query(queryString):
    to_run = prefixString + "\n" + queryString

    sparql = SPARQLWrapper("http://a256-gc1-03.srv.aau.dk:5820/sparql")
    sparql.setTimeout(300)
    sparql.setReturnFormat(JSON)
    sparql.setQuery(to_run)

    try :
        return sparql.query().convert()

    except Exception as e :
        print("The operation failed", e)

# %% [markdown]
# # History Workflow Series ("Literary Movements and Divine Comedy explorative search")
#
# Consider the following exploratory information need:
#
# > investigate the literary movements and the poets. In particular, compare some italian poets in terms of place of birth, number of literary works and education.

# %% [markdown]
# ## Useful URIs for the current workflow
# The following are given:
#
# | IRI           | Description   | Role      |
# | -----------   | -----------   |-----------|
# | `wdt:P1647`   | subproperty   | predicate |
# | `wdt:P31`     | instance of   | predicate |
# | `wdt:P106`    | occupation    | predicate |
# | `wdt:P279`    | subclass      | predicate |
# | `wdt:P27`     | nationality   | predicate |
# | `wdt:P3342`     | Significant person       | predicate |
# | `wd:Q5`| Human       | node |
# | `wd:Q40185`| The Divine Comedy  | node |

# %% [markdown]
# Also consider
#
# ```
# wd:Q40185 ?p ?obj .
# ```
#
# is the BGP to retrieve all **properties of The Divine Comedy**
#
# Please consider that when you return a resource, you should return the IRI and the label of the resource. In particular, when the task require you to identify a BGP the result set must always be a list of couples IRI - label.
#
# The workload should:
#
# 1. Who wrote The Divine Comedy? (return the IRI and the label of the author)
#
# 2. Identify the BGP for poet
#
# 3. Identify the BGP for literary movement
#
# 4. Return the poets born in the same place of the author of The Divine Comedy who are born between 1300 and 1500 (1300 and 1500 included) (the result set must be a list of couples poets IRI and label).
#
# 5. Identify the BGP for literary work
#
# 6. Compare the author of The Divine Comedy with Giovanni Boccaccio. Return for these poets the number of literary work they wrote (the result set must be two triples -one for each author- author IRI, label and #literary work).
#
# 7. Consider italian poets, their place of birth (the city) and their university education. Return for each city the number of poets who born there and who was educated there (the result set must be a list of triples city IRI, label and #poets).
#
# 8. Return the italian poets who won the Nobel Prize in Literature (the result set must be poet IRI and label).

# %% [markdown]
# ## Task 1
# Who wrote The Divine Comedy? (return the IRI and the label of the author)

# %%
# query example
queryString = """
SELECT DISTINCT ?p ?name
WHERE {
   # bind something
   wd:Q40185 ?p ?obj .
   # get the label
   # ?p sc:name ?name.
}
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P2551'), ('name', 'used metre')]
# [('p', 'http://www.wikidata.org/prop/direct/P1273'), ('name', 'CANTIC ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1296'), ('name', 'Gran Enciclopèdia Catalana ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1343'), ('name', 'described by source')]
# [('p', 'http://www.wikidata.org/prop/direct/P136'), ('name', 'genre')]
# [('p', 'http://www.wikidata.org/prop/direct/P1417'), ('name', 'Encyclopædia Britannica Online ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P18'), ('name', 'image')]
# [('p', 'http://www.wikidata.org/prop/direct/P1889'), ('name', 'different from')]
# [('p', 'http://www.wikidata.org/prop/direct/P214'), ('name', 'VIAF ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P227'), ('name', 'GND ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P244'), ('name', 'Library of Congress authority ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P268'), ('name', 'Bibliothèque nationale de France ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P269'), ('name', 'IdRef ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('name', 'instance of')]
# [('p', 'http://www.wikidata.org/prop/direct/P3219'), ('name', 'Encyclopædia Universalis ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3417'), ('name', 'Quora topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P373'), ('name', 'Commons category')]
# [('p', 'http://www.wikidata.org/prop/direct/P407'), ('name', 'language of work or name')]
# [('p', 'http://www.wikidata.org/prop/direct/P409'), ('name', 'Libraries Australia ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P435'), ('name', 'MusicBrainz work ID')]
# 20

# %%
# Get informations about instance of property
queryString = """
SELECT DISTINCT ?o ?name
WHERE {
   wd:Q40185 wdt:P31 ?o .
   # ?o sc:name ?name.
}
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('o', 'http://www.wikidata.org/entity/Q47461344'), ('name', 'written work')]
# 1

# %%
# Get informations about 'written work'
queryString = """
SELECT DISTINCT ?p ?name
WHERE {
   wd:Q47461344 ?p ?o .
   # ?p sc:name ?name.
}
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P1889'), ('name', 'different from')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('name', 'properties for this type')]
# [('p', 'http://www.wikidata.org/prop/direct/P2283'), ('name', 'uses')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('name', 'subclass of')]
# [('p', 'http://www.wikidata.org/prop/direct/P460'), ('name', 'said to be the same as')]
# [('p', 'http://www.wikidata.org/prop/direct/P8408'), ('name', 'KBpedia ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P910'), ('name', "topic's main category")]
# 7

# %%
# Get informations superclass of 'written work'
queryString = """
SELECT DISTINCT ?o ?name
WHERE {
   wd:Q47461344 wdt:P279 ?o .
   # ?o sc:name ?name.
}
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('o', 'http://www.wikidata.org/entity/Q17537576'), ('name', 'creative work')]
# 1

# %%
# Get informations about 'creative work'
queryString = """
SELECT DISTINCT ?p ?name
WHERE {
   wd:Q17537576 ?p ?o .
   # ?p sc:name ?name.
}
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P1552'), ('name', 'has quality')]
# [('p', 'http://www.wikidata.org/prop/direct/P1687'), ('name', 'Wikidata property')]
# [('p', 'http://www.wikidata.org/prop/direct/P1709'), ('name', 'equivalent class')]
# [('p', 'http://www.wikidata.org/prop/direct/P18'), ('name', 'image')]
# [('p', 'http://www.wikidata.org/prop/direct/P1889'), ('name', 'different from')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('name', 'properties for this type')]
# [('p', 'http://www.wikidata.org/prop/direct/P2283'), ('name', 'uses')]
# [('p', 'http://www.wikidata.org/prop/direct/P2671'), ('name', 'Google Knowledge Graph ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('name', 'subclass of')]
# [('p', 'http://www.wikidata.org/prop/direct/P373'), ('name', 'Commons category')]
# [('p', 'http://www.wikidata.org/prop/direct/P6366'), ('name', 'Microsoft Academic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P828'), ('name', 'has cause')]
# [('p', 'http://www.wikidata.org/prop/direct/P8408'), ('name', 'KBpedia ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8799'), ('name', 'Twitch tag ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P910'), ('name', "topic's main category")]
# [('p', 'http://www.wikidata.org/prop/direct/P1536'), ('name', 'immediate cause of')]
# 16

# %%
# Get informations about qualities of 'creative work'
queryString = """
SELECT DISTINCT ?quality ?name
WHERE {
   wd:Q17537576 wdt:P1552 ?quality .
   # ?quality sc:name ?name.
}
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('quality', 'http://www.wikidata.org/entity/Q170658'), ('name', 'creativity')]
# [('quality', 'http://www.wikidata.org/entity/Q73568642'), ('name', 'copyright status of works')]
# 2

# %%
# Get informations about 'properties for this type' of 'creative work'
queryString = """
SELECT DISTINCT ?prop ?name
WHERE {
   wd:Q17537576 wdt:P1963 ?prop .
   # ?prop sc:name ?name.
}
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('prop', 'http://www.wikidata.org/entity/P18'), ('name', 'image')]
# [('prop', 'http://www.wikidata.org/entity/P921'), ('name', 'main subject')]
# [('prop', 'http://www.wikidata.org/entity/P571'), ('name', 'inception')]
# [('prop', 'http://www.wikidata.org/entity/P856'), ('name', 'official website')]
# [('prop', 'http://www.wikidata.org/entity/P740'), ('name', 'location of formation')]
# [('prop', 'http://www.wikidata.org/entity/P170'), ('name', 'creator')]
# [('prop', 'http://www.wikidata.org/entity/P767'), ('name', 'contributor to the creative work or subject')]
# [('prop', 'http://www.wikidata.org/entity/P136'), ('name', 'genre')]
# [('prop', 'http://www.wikidata.org/entity/P1779'), ('name', 'possible creator')]
# [('prop', 'http://www.wikidata.org/entity/P272'), ('name', 'production company')]
# [('prop', 'http://www.wikidata.org/entity/P275'), ('name', 'copyright license')]
# [('prop', 'http://www.wikidata.org/entity/P859'), ('name', 'sponsor')]
# [('prop', 'http://www.wikidata.org/entity/P166'), ('name', 'award received')]
# [('prop', 'http://www.wikidata.org/entity/P144'), ('name', 'based on')]
# [('prop', 'http://www.wikidata.org/entity/P10'), ('name', 'video')]
# [('prop', 'http://www.wikidata.org/entity/P483'), ('name', 'recorded at studio or venue')]
# [('prop', 'http://www.wikidata.org/entity/P2360'), ('name', 'intended public')]
# 17

# %%
# Get informations about instance of property
queryString = """
SELECT DISTINCT ?creator ?name
WHERE {
   wd:Q40185 wdt:P170 ?creator .
   # ?creator sc:name ?name.
}
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# Empty

# %%
# Get informations about 'described by source' property
queryString = """
SELECT DISTINCT ?res ?name
WHERE {
   wd:Q40185 wdt:P1343 ?res .
   # ?res sc:name ?name.
}
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('res', 'http://www.wikidata.org/entity/Q2041543'), ('name', 'Ottův slovník naučný')]
# [('res', 'http://www.wikidata.org/entity/Q3181656'), ('name', 'The Nuttall Encyclopædia')]
# 2

# %%
# query example
queryString = """
SELECT DISTINCT ?p ?name
WHERE {
   wd:Q40185 ?p ?obj .
   # ?p sc:name ?name.
}
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P2551'), ('name', 'used metre')]
# [('p', 'http://www.wikidata.org/prop/direct/P1273'), ('name', 'CANTIC ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1296'), ('name', 'Gran Enciclopèdia Catalana ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1343'), ('name', 'described by source')]
# [('p', 'http://www.wikidata.org/prop/direct/P136'), ('name', 'genre')]
# [('p', 'http://www.wikidata.org/prop/direct/P1417'), ('name', 'Encyclopædia Britannica Online ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P18'), ('name', 'image')]
# [('p', 'http://www.wikidata.org/prop/direct/P1889'), ('name', 'different from')]
# [('p', 'http://www.wikidata.org/prop/direct/P214'), ('name', 'VIAF ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P227'), ('name', 'GND ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P244'), ('name', 'Library of Congress authority ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P268'), ('name', 'Bibliothèque nationale de France ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P269'), ('name', 'IdRef ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('name', 'instance of')]
# [('p', 'http://www.wikidata.org/prop/direct/P3219'), ('name', 'Encyclopædia Universalis ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3417'), ('name', 'Quora topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P373'), ('name', 'Commons category')]
# [('p', 'http://www.wikidata.org/prop/direct/P407'), ('name', 'language of work or name')]
# [('p', 'http://www.wikidata.org/prop/direct/P409'), ('name', 'Libraries Australia ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P435'), ('name', 'MusicBrainz work ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P50'), ('name', 'author')]
# [('p', 'http://www.wikidata.org/prop/direct/P5063'), ('name', 'Interlingual Index ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('name', 'has part')]
# [('p', 'http://www.wikidata.org/prop/direct/P571'), ('name', 'inception')]
# [('p', 'http://www.wikidata.org/prop/direct/P5986'), ('name', 'Getty Iconography Authority ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P646'), ('name', 'Freebase ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P674'), ('name', 'characters')]
# [('p', 'http://www.wikidata.org/prop/direct/P6839'), ('name', 'TV Tropes identifier')]
# [('p', 'http://www.wikidata.org/prop/direct/P691'), ('name', 'NKCR AUT ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7314'), ('name', 'TDV İslam Ansiklopedisi ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P747'), ('name', 'has edition or translation')]
# [('p', 'http://www.wikidata.org/prop/direct/P8189'), ('name', 'National Library of Israel J9U ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8248'), ('name', 'Colon Classification')]
# [('p', 'http://www.wikidata.org/prop/direct/P8408'), ('name', 'KBpedia ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8885'), ('name', 'Namuwiki ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P906'), ('name', 'SELIBR ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P910'), ('name', "topic's main category")]
# [('p', 'http://www.wikidata.org/prop/direct/P9223'), ('name', 'Provenio UUID')]
# [('p', 'http://www.wikidata.org/prop/direct/P9322'), ('name', 'SVKKL authority ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P949'), ('name', 'National Library of Israel ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P950'), ('name', 'Biblioteca Nacional de España ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1274'), ('name', 'ISFDB title ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6175'), ('name', 'Bitraga work ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8359'), ('name', 'Dewey Decimal Classification (works and editions)')]
# [('p', 'http://www.wikidata.org/prop/direct/P2034'), ('name', 'Project Gutenberg ebook ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3976'), ('name', 'BVMC work ID')]
# 46

# %%
# Get the author
queryString = """
SELECT DISTINCT ?author ?name
WHERE {
   wd:Q40185 wdt:P50 ?author .
   # ?author sc:name ?name.
}
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('author', 'http://www.wikidata.org/entity/Q1067'), ('name', 'Dante Alighieri')]
# 1

# %% [markdown]
# Final query for this task

# %%
queryString = """
SELECT DISTINCT ?author ?name
WHERE {
   wd:Q40185 wdt:P50 ?author .
   # ?author sc:name ?name.
}
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('author', 'http://www.wikidata.org/entity/Q1067'), ('name', 'Dante Alighieri')]
# 1

# %% [markdown]
# ## Task 2
# Identify the BGP for poet

# %%
# Get properties of 'Dante Alighieri'
queryString = """
SELECT DISTINCT ?p ?name
WHERE {
   wd:Q1067 ?p ?obj .
   # ?p sc:name ?name.
}
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P7992'), ('name', "Poeti d'Italia in lingua latina author ID")]
# [('p', 'http://www.wikidata.org/prop/direct/P1005'), ('name', 'Portuguese National Library ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1006'), ('name', 'Nationale Thesaurus voor Auteurs ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P101'), ('name', 'field of work')]
# [('p', 'http://www.wikidata.org/prop/direct/P1015'), ('name', 'NORAF ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1017'), ('name', 'Vatican Library ID (former scheme)')]
# [('p', 'http://www.wikidata.org/prop/direct/P103'), ('name', 'native language')]
# [('p', 'http://www.wikidata.org/prop/direct/P1036'), ('name', 'Dewey Decimal Classification')]
# [('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('p', 'http://www.wikidata.org/prop/direct/P1066'), ('name', 'student of')]
# [('p', 'http://www.wikidata.org/prop/direct/P1150'), ('name', 'Regensburg Classification')]
# [('p', 'http://www.wikidata.org/prop/direct/P119'), ('name', 'place of burial')]
# [('p', 'http://www.wikidata.org/prop/direct/P1196'), ('name', 'manner of death')]
# [('p', 'http://www.wikidata.org/prop/direct/P1207'), ('name', 'NUKAT ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1233'), ('name', 'Internet Speculative Fiction Database author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1256'), ('name', 'Iconclass notation')]
# [('p', 'http://www.wikidata.org/prop/direct/P1263'), ('name', 'NNDB people ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1273'), ('name', 'CANTIC ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1280'), ('name', 'CONOR.SI ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1296'), ('name', 'Gran Enciclopèdia Catalana ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1299'), ('name', 'depicted by')]
# [('p', 'http://www.wikidata.org/prop/direct/P1309'), ('name', 'EGAXA ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1315'), ('name', 'NLA Trove ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1343'), ('name', 'described by source')]
# [('p', 'http://www.wikidata.org/prop/direct/P135'), ('name', 'movement')]
# [('p', 'http://www.wikidata.org/prop/direct/P1368'), ('name', 'LNB ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1375'), ('name', 'NSK ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P140'), ('name', 'religion')]
# [('p', 'http://www.wikidata.org/prop/direct/P1412'), ('name', 'languages spoken, written or signed')]
# [('p', 'http://www.wikidata.org/prop/direct/P1417'), ('name', 'Encyclopædia Britannica Online ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1422'), ('name', 'Sandrart.net person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1472'), ('name', 'Commons Creator page')]
# [('p', 'http://www.wikidata.org/prop/direct/P1580'), ('name', 'University of Barcelona authority ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1670'), ('name', 'Canadiana Authorities ID (former scheme)')]
# [('p', 'http://www.wikidata.org/prop/direct/P1695'), ('name', 'NLP ID (unique)')]
# [('p', 'http://www.wikidata.org/prop/direct/P1711'), ('name', 'British Museum person or institution ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P172'), ('name', 'ethnic group')]
# [('p', 'http://www.wikidata.org/prop/direct/P1728'), ('name', 'AllMusic artist ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1741'), ('name', 'GTAA ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P18'), ('name', 'image')]
# [('p', 'http://www.wikidata.org/prop/direct/P1871'), ('name', 'CERL Thesaurus ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1890'), ('name', 'CCAB ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1899'), ('name', 'LibriVox author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P19'), ('name', 'place of birth')]
# [('p', 'http://www.wikidata.org/prop/direct/P1938'), ('name', 'Project Gutenberg author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1953'), ('name', 'Discogs artist ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1977'), ('name', 'Les Archives du Spectacle Person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1986'), ('name', 'Biographical Dictionary of Italian People ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P20'), ('name', 'place of death')]
# [('p', 'http://www.wikidata.org/prop/direct/P2031'), ('name', 'work period (start)')]
# [('p', 'http://www.wikidata.org/prop/direct/P21'), ('name', 'sex or gender')]
# [('p', 'http://www.wikidata.org/prop/direct/P213'), ('name', 'ISNI')]
# [('p', 'http://www.wikidata.org/prop/direct/P214'), ('name', 'VIAF ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2163'), ('name', 'FAST ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2188'), ('name', 'BiblioNet author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P22'), ('name', 'father')]
# [('p', 'http://www.wikidata.org/prop/direct/P2252'), ('name', 'National Gallery of Art artist ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P227'), ('name', 'GND ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2342'), ('name', 'AGORHA person/institution ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P244'), ('name', 'Library of Congress authority ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P245'), ('name', 'Union List of Artist Names ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P25'), ('name', 'mother')]
# [('p', 'http://www.wikidata.org/prop/direct/P2510'), ('name', 'National Discography of Italian Song artist/group ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2533'), ('name', 'WomenWriters ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2581'), ('name', 'BabelNet ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P26'), ('name', 'spouse')]
# [('p', 'http://www.wikidata.org/prop/direct/P2600'), ('name', 'Geni.com profile ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2639'), ('name', 'Filmportal ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P268'), ('name', 'Bibliothèque nationale de France ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P269'), ('name', 'IdRef ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P27'), ('name', 'country of citizenship')]
# [('p', 'http://www.wikidata.org/prop/direct/P271'), ('name', 'CiNii author ID (books)')]
# [('p', 'http://www.wikidata.org/prop/direct/P2734'), ('name', 'Unz Review author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2799'), ('name', 'BVMC person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2924'), ('name', 'Great Russian Encyclopedia Online ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2949'), ('name', 'WikiTree person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2966'), ('name', 'National Library of Wales Authority ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2977'), ('name', 'LBT person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3065'), ('name', 'RERO ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('name', 'instance of')]
# [('p', 'http://www.wikidata.org/prop/direct/P3123'), ('name', 'Stanford Encyclopedia of Philosophy ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3126'), ('name', 'ALCUIN ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3154'), ('name', 'Runeberg author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3192'), ('name', 'Last.fm ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3219'), ('name', 'Encyclopædia Universalis ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3222'), ('name', 'NE.se ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3241'), ('name', 'Catholic Encyclopedia ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3280'), ('name', 'BAnQ author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3348'), ('name', 'National Library of Greece ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3365'), ('name', 'Treccani ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3373'), ('name', 'sibling')]
# [('p', 'http://www.wikidata.org/prop/direct/P3417'), ('name', 'Quora topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3430'), ('name', 'SNAC ARK ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P345'), ('name', 'IMDb ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P349'), ('name', 'National Diet Library ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3544'), ('name', 'Te Papa agent ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3553'), ('name', 'Zhihu topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3569'), ('name', 'Cultureel Woordenboek ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3603'), ('name', 'Minneapolis Institute of Art constituent ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3630'), ('name', 'Babelio author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P373'), ('name', 'Commons category')]
# [('p', 'http://www.wikidata.org/prop/direct/P3762'), ('name', 'openMLOL author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3788'), ('name', 'BNMM authority ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3846'), ('name', 'DBC author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P396'), ('name', 'SBN author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3965'), ('name', 'Bridgeman artist ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3987'), ('name', 'SHARE Catalogue author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P40'), ('name', 'child')]
# [('p', 'http://www.wikidata.org/prop/direct/P4084'), ('name', 'MyAnimeList people ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P409'), ('name', 'Libraries Australia ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P4104'), ('name', 'Carnegie Hall agent ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P4145'), ('name', 'Athenaeum person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P4200'), ('name', "Christie's creator ID")]
# [('p', 'http://www.wikidata.org/prop/direct/P4223'), ('name', "Treccani's Enciclopedia Italiana ID")]
# [('p', 'http://www.wikidata.org/prop/direct/P434'), ('name', 'MusicBrainz artist ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P4342'), ('name', 'Store norske leksikon ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P4359'), ('name', 'gravsted.dk ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P437'), ('name', 'distribution format')]
# [('p', 'http://www.wikidata.org/prop/direct/P4399'), ('name', 'Itaú Cultural ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P4457'), ('name', 'DAHR artist ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P4491'), ('name', 'Isidore scholar ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P4539'), ('name', 'Collective Biographies of Women ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P4549'), ('name', 'ARLIMA ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P4553'), ('name', 'RA Collections ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P4619'), ('name', 'National Library of Brazil ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P4629'), ('name', 'Online Books Page author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P463'), ('name', 'member of')]
# [('p', 'http://www.wikidata.org/prop/direct/P4808'), ('name', 'Royal Academy new identifier')]
# [('p', 'http://www.wikidata.org/prop/direct/P4985'), ('name', 'TMDb person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5002'), ('name', 'Orthodox Encyclopedia ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5008'), ('name', 'on focus list of Wikimedia project')]
# [('p', 'http://www.wikidata.org/prop/direct/P5019'), ('name', 'Brockhaus Enzyklopädie online ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5034'), ('name', 'National Library of Korea ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5063'), ('name', 'Interlingual Index ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5068'), ('name', 'Flanders Arts Institute person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P509'), ('name', 'cause of death')]
# [('p', 'http://www.wikidata.org/prop/direct/P5101'), ('name', 'Swedish Literature Bank Author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P53'), ('name', 'family')]
# [('p', 'http://www.wikidata.org/prop/direct/P5341'), ('name', 'Poetry Foundation ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5343'), ('name', 'Poets.org poet ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5344'), ('name', 'Printemps des poètes poet ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P535'), ('name', 'Find A Grave memorial ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5357'), ('name', 'The Encyclopedia of Science Fiction ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5361'), ('name', 'BNB person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5365'), ('name', 'Internet Book Database of Fiction writer ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5375'), ('name', 'BIU Santé person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5421'), ('name', 'Trading Card Database person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5491'), ('name', "BD Gest' author ID")]
# [('p', 'http://www.wikidata.org/prop/direct/P5492'), ('name', 'EDIT16 catalogue author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5503'), ('name', 'Poetry Society of America poet ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5504'), ('name', 'RISM ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P551'), ('name', 'residence')]
# [('p', 'http://www.wikidata.org/prop/direct/P5587'), ('name', 'Libris-URI')]
# [('p', 'http://www.wikidata.org/prop/direct/P5613'), ('name', 'Bibliothèque de la Pléiade ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P569'), ('name', 'date of birth')]
# [('p', 'http://www.wikidata.org/prop/direct/P570'), ('name', 'date of death')]
# [('p', 'http://www.wikidata.org/prop/direct/P5731'), ('name', 'Angelicum ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5739'), ('name', 'Pontificia Università della Santa Croce ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5821'), ('name', 'ArhivX LOD')]
# [('p', 'http://www.wikidata.org/prop/direct/P5905'), ('name', 'Comic Vine ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6058'), ('name', 'Larousse ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P607'), ('name', 'conflict')]
# [('p', 'http://www.wikidata.org/prop/direct/P611'), ('name', 'religious order')]
# [('p', 'http://www.wikidata.org/prop/direct/P6173'), ('name', 'Bitraga author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6300'), ('name', 'Hymnary author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6327'), ('name', 'Goodreads character ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6379'), ('name', 'has works in the collection')]
# [('p', 'http://www.wikidata.org/prop/direct/P6394'), ('name', 'ELNET ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6403'), ('name', 'TheatreOnline ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6404'), ('name', "Treccani's Dizionario di Storia ID")]
# [('p', 'http://www.wikidata.org/prop/direct/P6412'), ('name', 'Gran Enciclopèdia de la Música ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P646'), ('name', 'Freebase ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P648'), ('name', 'Open Library ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P650'), ('name', 'RKDartists ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6573'), ('name', 'Klexikon article ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6578'), ('name', 'MutualArt artist ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6656'), ('name', 'BHCL ID (former scheme)')]
# [('p', 'http://www.wikidata.org/prop/direct/P6683'), ('name', 'Alexander Turnbull Library ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6745'), ('name', 'Orlando author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6764'), ('name', 'V&A person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6821'), ('name', 'Uppsala University Alvin ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6844'), ('name', 'abART person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6873'), ('name', 'IntraText author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6886'), ('name', 'writing language')]
# [('p', 'http://www.wikidata.org/prop/direct/P691'), ('name', 'NKCR AUT ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7024'), ('name', 'Flemish Public Libraries ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7026'), ('name', 'Lebanese National Library ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7029'), ('name', 'National Library of Russia ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7039'), ('name', 'National Library of Iceland ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7041'), ('name', 'Perseus author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7042'), ('name', 'The Latin Library author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7208'), ('name', 'Liber Liber author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7212'), ('name', 'LyricsTranslate ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P723'), ('name', 'Digitale Bibliotheek voor de Nederlandse Letteren author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7293'), ('name', 'PLWABN ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7311'), ('name', 'Aozora Bunko author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P734'), ('name', 'family name')]
# [('p', 'http://www.wikidata.org/prop/direct/P735'), ('name', 'given name')]
# [('p', 'http://www.wikidata.org/prop/direct/P7369'), ('name', 'National Library of Chile ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P737'), ('name', 'influenced by')]
# [('p', 'http://www.wikidata.org/prop/direct/P7388'), ('name', 'Great Encyclopedia of Navarre ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7400'), ('name', 'LibraryThing author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7433'), ('name', 'FantLab author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7444'), ('name', 'Rijksmuseum Research Library authority ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7507'), ('name', 'Ben Yehuda author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7666'), ('name', 'Visuotinė lietuvių enciklopedija ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7699'), ('name', 'National Library of Lithuania ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7700'), ('name', 'Slovak National Library ID (VIAF)')]
# [('p', 'http://www.wikidata.org/prop/direct/P7704'), ('name', 'Europeana entity')]
# [('p', 'http://www.wikidata.org/prop/direct/P7711'), ('name', 'Joconde author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7744'), ('name', 'Mille Anni di Scienza in Italia ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7753'), ('name', 'Projekt Gutenberg-DE ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7763'), ('name', 'copyright status as a creator')]
# [('p', 'http://www.wikidata.org/prop/direct/P7796'), ('name', 'BeWeb person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7818'), ('name', 'French Vikidia ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7822'), ('name', 'Italian Vikidia ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7859'), ('name', 'WorldCat Identities ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7865'), ('name', 'CoBiS author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7902'), ('name', 'Deutsche Biographie (GND) ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7929'), ('name', 'Roglo person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7935'), ('name', 'Corpus Corporum author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7982'), ('name', 'Hrvatska enciklopedija ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7986'), ('name', 'Mirabile author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7993'), ('name', "Treccani's Dizionario di Filosofia ID")]
# [('p', 'http://www.wikidata.org/prop/direct/P800'), ('name', 'notable work')]
# [('p', 'http://www.wikidata.org/prop/direct/P8034'), ('name', 'Vatican Library VcBA ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8122'), ('name', 'DLL Catalog author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8179'), ('name', 'Canadiana NCF ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8189'), ('name', 'National Library of Israel J9U ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8234'), ('name', 'LiederNet author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8248'), ('name', 'Colon Classification')]
# [('p', 'http://www.wikidata.org/prop/direct/P8287'), ('name', 'Worlds Without End author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8290'), ('name', 'Archivio Storico Ricordi person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8334'), ('name', 'MuseScore artist ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8349'), ('name', 'Proleksis enciklopedija ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8385'), ('name', 'IDU person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P839'), ('name', 'IMSLP ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8406'), ('name', 'Grove Art Online ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8440'), ('name', 'Personendatenbank Germania Sacra ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8496'), ('name', 'Archive Site Trinity College Cambridge ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8547'), ('name', 'BHF author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8568'), ('name', 'Jewish Virtual Library ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8625'), ('name', 'bibliography')]
# [('p', 'http://www.wikidata.org/prop/direct/P863'), ('name', 'InPhO ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8636'), ('name', 'McClintock and Strong Biblical Cyclopedia ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P866'), ('name', 'Perlentaucher ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8750'), ('name', 'Unione Romana Biblioteche Scientifiche ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8795'), ('name', 'General Diamond Catalogue ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8805'), ('name', 'LIMIS person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8814'), ('name', 'WordNet 3.1 Synset ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8826'), ('name', 'edition humboldt digital ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8833'), ('name', 'Union Catalog of Armenian Libraries authority ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8848'), ('name', 'CONOR.AL ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8849'), ('name', 'CONOR.BG ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8851'), ('name', 'CONOR.SR ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8885'), ('name', 'Namuwiki ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8899'), ('name', 'Swedish National Library Arken ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8902'), ('name', 'Archives at Yale names ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8947'), ('name', 'Museo Galileo authority ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8974'), ('name', 'SAPA ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8980'), ('name', 'KANTO ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P9000'), ('name', 'World History Encyclopedia ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P9017'), ('name', 'Medieval Manuscripts in Oxford Libraries person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P9037'), ('name', 'BHCL UUID')]
# [('p', 'http://www.wikidata.org/prop/direct/P906'), ('name', 'SELIBR ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P9081'), ('name', 'SEARCH on line catalogue ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P910'), ('name', "topic's main category")]
# [('p', 'http://www.wikidata.org/prop/direct/P9141'), ('name', 'Portal da Literatura ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P9164'), ('name', 'Svenska Institutet i Rom ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P9171'), ('name', 'RILM ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P9178'), ('name', 'Biblioteca Franco Serantini ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P9179'), ('name', 'Biblioteca Iglesia Nacional Española en Roma ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P9223'), ('name', 'Provenio UUID')]
# [('p', 'http://www.wikidata.org/prop/direct/P9226'), ('name', 'ARAE ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P9251'), ('name', 'Cyprus University of Technology ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P9282'), ('name', 'Catalogue of the Capitular Library of Verona author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P935'), ('name', 'Commons gallery')]
# [('p', 'http://www.wikidata.org/prop/direct/P9407'), ('name', 'Polignosi ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P949'), ('name', 'National Library of Israel ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P950'), ('name', 'Biblioteca Nacional de España ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P9507'), ('name', 'NBM authority ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P9522'), ('name', 'Biblioteca di Santa Sabina ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P9534'), ('name', 'Biblioteche della Custodia di Terra Santa a Gerusalemme ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P9536'), ('name', 'SAIA authority ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P9563'), ('name', 'Encyclopedia of Renaissance Philosophy ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P9626'), ('name', 'Biographical Encyclopedia of Astronomers ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P9653'), ('name', 'Bod-Inc Online author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P9661'), ('name', 'EBAF authority ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P9678'), ('name', 'Franciscan Center of Christian Oriental Studies ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P9756'), ('name', 'Schoenberg Database of Manuscripts name ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P9807'), ('name', 'SNK ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P4440'), ('name', 'Biblioteca Nacional de México ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7331'), ('name', 'Letteraturaitaliana.net author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P9575'), ('name', 'Australian Music Centre artist ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8603'), ('name', 'Istrapedia ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P9041'), ('name', 'DiVo person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P9642'), ('name', 'Olschki author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6583'), ('name', 'Lucerna person ID')]
# 298

# %%
# 'Dante Alighieri' occupation
queryString = """
SELECT DISTINCT ?occupation ?name
WHERE {
   wd:Q1067 wdt:P106 ?occupation .
   # ?occupation sc:name ?name.
}
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('occupation', 'http://www.wikidata.org/entity/Q12144794'), ('name', 'prosaist')]
# [('occupation', 'http://www.wikidata.org/entity/Q15994177'), ('name', 'political theorist')]
# [('occupation', 'http://www.wikidata.org/entity/Q36180'), ('name', 'writer')]
# [('occupation', 'http://www.wikidata.org/entity/Q482980'), ('name', 'author')]
# [('occupation', 'http://www.wikidata.org/entity/Q4964182'), ('name', 'philosopher')]
# [('occupation', 'http://www.wikidata.org/entity/Q49757'), ('name', 'poet')]
# [('occupation', 'http://www.wikidata.org/entity/Q822146'), ('name', 'lyricist')]
# [('occupation', 'http://www.wikidata.org/entity/Q82955'), ('name', 'politician')]
# [('occupation', 'http://www.wikidata.org/entity/Q58968'), ('name', 'intellectual')]
# 9

# %% [markdown]
# Final query for this task

# %%
# 'Dante Alighieri' occupation
queryString = """
SELECT DISTINCT ?occupation ?name
WHERE {
   wd:Q1067 wdt:P106 ?occupation .
   # ?occupation sc:name ?name.
   FILTER REGEX(?name, "[Pp]oet")
}
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('occupation', 'http://www.wikidata.org/entity/Q49757'), ('name', 'poet')]
# 1

# %% [markdown]
# ## Task 3
# Identify the BGP for literary movement

# %%
# 'Dante Alighieri' movement
queryString = """
SELECT DISTINCT ?mov ?name
WHERE {
   wd:Q1067 wdt:P135 ?mov .
   # ?mov sc:name ?name.
}
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('mov', 'http://www.wikidata.org/entity/Q542036'), ('name', 'Dolce Stil Novo')]
# 1

# %%
# Get properties for 'Dolce Stil Novo'
queryString = """
SELECT DISTINCT ?p ?name
WHERE {
   wd:Q542036 ?p ?obj .
   # ?p sc:name ?name.
}
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P1296'), ('name', 'Gran Enciclopèdia Catalana ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1417'), ('name', 'Encyclopædia Britannica Online ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P244'), ('name', 'Library of Congress authority ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2924'), ('name', 'Great Russian Encyclopedia Online ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('name', 'instance of')]
# [('p', 'http://www.wikidata.org/prop/direct/P3219'), ('name', 'Encyclopædia Universalis ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3365'), ('name', 'Treccani ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P4223'), ('name', "Treccani's Enciclopedia Italiana ID")]
# [('p', 'http://www.wikidata.org/prop/direct/P495'), ('name', 'country of origin')]
# [('p', 'http://www.wikidata.org/prop/direct/P508'), ('name', 'BNCF Thesaurus ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P646'), ('name', 'Freebase ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7982'), ('name', 'Hrvatska enciklopedija ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P910'), ('name', "topic's main category")]
# 13

# %% [markdown]
# Final query for this task

# %%
# Get class of 'Dolce Stil Novo'
queryString = """
SELECT DISTINCT ?class ?name
WHERE {
   wd:Q542036 wdt:P31 ?class .
   # ?class sc:name ?name.
}
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('class', 'http://www.wikidata.org/entity/Q3326717'), ('name', 'literary movement')]
# 1

# %% [markdown]
# ## Task 4
# Return the poets born in the same place of the author of The Divine Comedy who are born between 1300 and 1500 (1300 and 1500 included) (the result set must be a list of couples poets IRI and label).

# %%
# Get all the properties of a Poet
queryString = """
SELECT DISTINCT ?p ?name
WHERE {
   wd:Q49757 ?p ?obj .
   # ?p sc:name ?name.
}
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P1014'), ('name', 'Art & Architecture Thesaurus ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1296'), ('name', 'Gran Enciclopèdia Catalana ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1343'), ('name', 'described by source')]
# [('p', 'http://www.wikidata.org/prop/direct/P1709'), ('name', 'equivalent class')]
# [('p', 'http://www.wikidata.org/prop/direct/P1889'), ('name', 'different from')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('name', 'properties for this type')]
# [('p', 'http://www.wikidata.org/prop/direct/P227'), ('name', 'GND ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P244'), ('name', 'Library of Congress authority ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2581'), ('name', 'BabelNet ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P268'), ('name', 'Bibliothèque nationale de France ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('name', 'subclass of')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('name', 'instance of')]
# [('p', 'http://www.wikidata.org/prop/direct/P3417'), ('name', 'Quora topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P349'), ('name', 'National Diet Library ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3553'), ('name', 'Zhihu topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P373'), ('name', 'Commons category')]
# [('p', 'http://www.wikidata.org/prop/direct/P3916'), ('name', 'UNESCO Thesaurus ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P4212'), ('name', 'PACTOLS thesaurus ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P425'), ('name', 'field of this occupation')]
# [('p', 'http://www.wikidata.org/prop/direct/P460'), ('name', 'said to be the same as')]
# [('p', 'http://www.wikidata.org/prop/direct/P508'), ('name', 'BNCF Thesaurus ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5160'), ('name', 'Thesaurus for Graphic Materials ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6186'), ('name', 'category for eponymous categories')]
# [('p', 'http://www.wikidata.org/prop/direct/P6262'), ('name', 'Fandom article ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P646'), ('name', 'Freebase ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7033'), ('name', 'Australian Educational Vocabulary ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8408'), ('name', 'KBpedia ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8519'), ('name', 'RKD thesaurus ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8814'), ('name', 'WordNet 3.1 Synset ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P910'), ('name', "topic's main category")]
# [('p', 'http://www.wikidata.org/prop/direct/P950'), ('name', 'Biblioteca Nacional de España ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P867'), ('name', 'ROME Occupation Code (v3)')]
# 32

# %%
# Get all subjects that have 'poet' as 'occupation' 
queryString = """
SELECT DISTINCT ?poet ?name
WHERE {
   # ?poet wdt:P106 wd:Q49757 .
   # ?poet sc:name ?name.
}
LIMIT 10
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('poet', 'http://www.wikidata.org/entity/Q1373516'), ('name', 'Eugénio de Castro')]
# [('poet', 'http://www.wikidata.org/entity/Q589406'), ('name', 'Empress Xiaoquancheng')]
# [('poet', 'http://www.wikidata.org/entity/Q610608'), ('name', 'António Aleixo')]
# [('poet', 'http://www.wikidata.org/entity/Q710504'), ('name', 'Bohuslav Balbín')]
# [('poet', 'http://www.wikidata.org/entity/Q8188119'), ('name', 'Adelina Lopes Vieira')]
# [('poet', 'http://www.wikidata.org/entity/Q8201526'), ('name', 'Antonio Márquez Salas')]
# [('poet', 'http://www.wikidata.org/entity/Q8201629'), ('name', 'Antonio Rendic')]
# [('poet', 'http://www.wikidata.org/entity/Q8202094'), ('name', 'Antônio de Castro Assumpção')]
# [('poet', 'http://www.wikidata.org/entity/Q8246828'), ('name', 'Bernat Català de Valleriola')]
# [('poet', 'http://www.wikidata.org/entity/Q1191225'), ('name', 'Tan Sitong')]
# 10

# %%
# Get all subjects that have 'poet' as 'occupation' 
queryString = """
SELECT DISTINCT ?poet ?name
WHERE {
   # ?poet wdt:P106 wd:Q49757 .
   # ?poet sc:name ?name.
}
LIMIT 10
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('poet', 'http://www.wikidata.org/entity/Q1373516'), ('name', 'Eugénio de Castro')]
# [('poet', 'http://www.wikidata.org/entity/Q589406'), ('name', 'Empress Xiaoquancheng')]
# [('poet', 'http://www.wikidata.org/entity/Q610608'), ('name', 'António Aleixo')]
# [('poet', 'http://www.wikidata.org/entity/Q710504'), ('name', 'Bohuslav Balbín')]
# [('poet', 'http://www.wikidata.org/entity/Q8188119'), ('name', 'Adelina Lopes Vieira')]
# [('poet', 'http://www.wikidata.org/entity/Q8201526'), ('name', 'Antonio Márquez Salas')]
# [('poet', 'http://www.wikidata.org/entity/Q8201629'), ('name', 'Antonio Rendic')]
# [('poet', 'http://www.wikidata.org/entity/Q8202094'), ('name', 'Antônio de Castro Assumpção')]
# [('poet', 'http://www.wikidata.org/entity/Q8246828'), ('name', 'Bernat Català de Valleriola')]
# [('poet', 'http://www.wikidata.org/entity/Q1191225'), ('name', 'Tan Sitong')]
# 10

# %%
# Get all the properties of 'Dante Alighieri'
queryString = """
SELECT DISTINCT ?p ?name
WHERE {
   wd:Q1067 ?p ?obj .
   # ?p sc:name ?name.
}
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P7992'), ('name', "Poeti d'Italia in lingua latina author ID")]
# [('p', 'http://www.wikidata.org/prop/direct/P1005'), ('name', 'Portuguese National Library ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1006'), ('name', 'Nationale Thesaurus voor Auteurs ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P101'), ('name', 'field of work')]
# [('p', 'http://www.wikidata.org/prop/direct/P1015'), ('name', 'NORAF ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1017'), ('name', 'Vatican Library ID (former scheme)')]
# [('p', 'http://www.wikidata.org/prop/direct/P103'), ('name', 'native language')]
# [('p', 'http://www.wikidata.org/prop/direct/P1036'), ('name', 'Dewey Decimal Classification')]
# [('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('p', 'http://www.wikidata.org/prop/direct/P1066'), ('name', 'student of')]
# [('p', 'http://www.wikidata.org/prop/direct/P1150'), ('name', 'Regensburg Classification')]
# [('p', 'http://www.wikidata.org/prop/direct/P119'), ('name', 'place of burial')]
# [('p', 'http://www.wikidata.org/prop/direct/P1196'), ('name', 'manner of death')]
# [('p', 'http://www.wikidata.org/prop/direct/P1207'), ('name', 'NUKAT ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1233'), ('name', 'Internet Speculative Fiction Database author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1256'), ('name', 'Iconclass notation')]
# [('p', 'http://www.wikidata.org/prop/direct/P1263'), ('name', 'NNDB people ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1273'), ('name', 'CANTIC ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1280'), ('name', 'CONOR.SI ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1296'), ('name', 'Gran Enciclopèdia Catalana ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1299'), ('name', 'depicted by')]
# [('p', 'http://www.wikidata.org/prop/direct/P1309'), ('name', 'EGAXA ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1315'), ('name', 'NLA Trove ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1343'), ('name', 'described by source')]
# [('p', 'http://www.wikidata.org/prop/direct/P135'), ('name', 'movement')]
# [('p', 'http://www.wikidata.org/prop/direct/P1368'), ('name', 'LNB ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1375'), ('name', 'NSK ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P140'), ('name', 'religion')]
# [('p', 'http://www.wikidata.org/prop/direct/P1412'), ('name', 'languages spoken, written or signed')]
# [('p', 'http://www.wikidata.org/prop/direct/P1417'), ('name', 'Encyclopædia Britannica Online ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1422'), ('name', 'Sandrart.net person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1472'), ('name', 'Commons Creator page')]
# [('p', 'http://www.wikidata.org/prop/direct/P1580'), ('name', 'University of Barcelona authority ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1670'), ('name', 'Canadiana Authorities ID (former scheme)')]
# [('p', 'http://www.wikidata.org/prop/direct/P1695'), ('name', 'NLP ID (unique)')]
# [('p', 'http://www.wikidata.org/prop/direct/P1711'), ('name', 'British Museum person or institution ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P172'), ('name', 'ethnic group')]
# [('p', 'http://www.wikidata.org/prop/direct/P1728'), ('name', 'AllMusic artist ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1741'), ('name', 'GTAA ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P18'), ('name', 'image')]
# [('p', 'http://www.wikidata.org/prop/direct/P1871'), ('name', 'CERL Thesaurus ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1890'), ('name', 'CCAB ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1899'), ('name', 'LibriVox author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P19'), ('name', 'place of birth')]
# [('p', 'http://www.wikidata.org/prop/direct/P1938'), ('name', 'Project Gutenberg author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1953'), ('name', 'Discogs artist ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1977'), ('name', 'Les Archives du Spectacle Person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1986'), ('name', 'Biographical Dictionary of Italian People ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P20'), ('name', 'place of death')]
# [('p', 'http://www.wikidata.org/prop/direct/P2031'), ('name', 'work period (start)')]
# [('p', 'http://www.wikidata.org/prop/direct/P21'), ('name', 'sex or gender')]
# [('p', 'http://www.wikidata.org/prop/direct/P213'), ('name', 'ISNI')]
# [('p', 'http://www.wikidata.org/prop/direct/P214'), ('name', 'VIAF ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2163'), ('name', 'FAST ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2188'), ('name', 'BiblioNet author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P22'), ('name', 'father')]
# [('p', 'http://www.wikidata.org/prop/direct/P2252'), ('name', 'National Gallery of Art artist ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P227'), ('name', 'GND ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2342'), ('name', 'AGORHA person/institution ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P244'), ('name', 'Library of Congress authority ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P245'), ('name', 'Union List of Artist Names ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P25'), ('name', 'mother')]
# [('p', 'http://www.wikidata.org/prop/direct/P2510'), ('name', 'National Discography of Italian Song artist/group ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2533'), ('name', 'WomenWriters ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2581'), ('name', 'BabelNet ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P26'), ('name', 'spouse')]
# [('p', 'http://www.wikidata.org/prop/direct/P2600'), ('name', 'Geni.com profile ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2639'), ('name', 'Filmportal ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P268'), ('name', 'Bibliothèque nationale de France ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P269'), ('name', 'IdRef ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P27'), ('name', 'country of citizenship')]
# [('p', 'http://www.wikidata.org/prop/direct/P271'), ('name', 'CiNii author ID (books)')]
# [('p', 'http://www.wikidata.org/prop/direct/P2734'), ('name', 'Unz Review author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2799'), ('name', 'BVMC person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2924'), ('name', 'Great Russian Encyclopedia Online ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2949'), ('name', 'WikiTree person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2966'), ('name', 'National Library of Wales Authority ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2977'), ('name', 'LBT person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3065'), ('name', 'RERO ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('name', 'instance of')]
# [('p', 'http://www.wikidata.org/prop/direct/P3123'), ('name', 'Stanford Encyclopedia of Philosophy ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3126'), ('name', 'ALCUIN ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3154'), ('name', 'Runeberg author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3192'), ('name', 'Last.fm ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3219'), ('name', 'Encyclopædia Universalis ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3222'), ('name', 'NE.se ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3241'), ('name', 'Catholic Encyclopedia ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3280'), ('name', 'BAnQ author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3348'), ('name', 'National Library of Greece ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3365'), ('name', 'Treccani ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3373'), ('name', 'sibling')]
# [('p', 'http://www.wikidata.org/prop/direct/P3417'), ('name', 'Quora topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3430'), ('name', 'SNAC ARK ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P345'), ('name', 'IMDb ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P349'), ('name', 'National Diet Library ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3544'), ('name', 'Te Papa agent ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3553'), ('name', 'Zhihu topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3569'), ('name', 'Cultureel Woordenboek ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3603'), ('name', 'Minneapolis Institute of Art constituent ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3630'), ('name', 'Babelio author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P373'), ('name', 'Commons category')]
# [('p', 'http://www.wikidata.org/prop/direct/P3762'), ('name', 'openMLOL author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3788'), ('name', 'BNMM authority ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3846'), ('name', 'DBC author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P396'), ('name', 'SBN author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3965'), ('name', 'Bridgeman artist ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3987'), ('name', 'SHARE Catalogue author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P40'), ('name', 'child')]
# [('p', 'http://www.wikidata.org/prop/direct/P4084'), ('name', 'MyAnimeList people ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P409'), ('name', 'Libraries Australia ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P4104'), ('name', 'Carnegie Hall agent ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P4145'), ('name', 'Athenaeum person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P4200'), ('name', "Christie's creator ID")]
# [('p', 'http://www.wikidata.org/prop/direct/P4223'), ('name', "Treccani's Enciclopedia Italiana ID")]
# [('p', 'http://www.wikidata.org/prop/direct/P434'), ('name', 'MusicBrainz artist ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P4342'), ('name', 'Store norske leksikon ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P4359'), ('name', 'gravsted.dk ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P437'), ('name', 'distribution format')]
# [('p', 'http://www.wikidata.org/prop/direct/P4399'), ('name', 'Itaú Cultural ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P4457'), ('name', 'DAHR artist ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P4491'), ('name', 'Isidore scholar ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P4539'), ('name', 'Collective Biographies of Women ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P4549'), ('name', 'ARLIMA ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P4553'), ('name', 'RA Collections ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P4619'), ('name', 'National Library of Brazil ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P4629'), ('name', 'Online Books Page author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P463'), ('name', 'member of')]
# [('p', 'http://www.wikidata.org/prop/direct/P4808'), ('name', 'Royal Academy new identifier')]
# [('p', 'http://www.wikidata.org/prop/direct/P4985'), ('name', 'TMDb person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5002'), ('name', 'Orthodox Encyclopedia ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5008'), ('name', 'on focus list of Wikimedia project')]
# [('p', 'http://www.wikidata.org/prop/direct/P5019'), ('name', 'Brockhaus Enzyklopädie online ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5034'), ('name', 'National Library of Korea ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5063'), ('name', 'Interlingual Index ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5068'), ('name', 'Flanders Arts Institute person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P509'), ('name', 'cause of death')]
# [('p', 'http://www.wikidata.org/prop/direct/P5101'), ('name', 'Swedish Literature Bank Author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P53'), ('name', 'family')]
# [('p', 'http://www.wikidata.org/prop/direct/P5341'), ('name', 'Poetry Foundation ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5343'), ('name', 'Poets.org poet ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5344'), ('name', 'Printemps des poètes poet ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P535'), ('name', 'Find A Grave memorial ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5357'), ('name', 'The Encyclopedia of Science Fiction ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5361'), ('name', 'BNB person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5365'), ('name', 'Internet Book Database of Fiction writer ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5375'), ('name', 'BIU Santé person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5421'), ('name', 'Trading Card Database person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5491'), ('name', "BD Gest' author ID")]
# [('p', 'http://www.wikidata.org/prop/direct/P5492'), ('name', 'EDIT16 catalogue author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5503'), ('name', 'Poetry Society of America poet ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5504'), ('name', 'RISM ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P551'), ('name', 'residence')]
# [('p', 'http://www.wikidata.org/prop/direct/P5587'), ('name', 'Libris-URI')]
# [('p', 'http://www.wikidata.org/prop/direct/P5613'), ('name', 'Bibliothèque de la Pléiade ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P569'), ('name', 'date of birth')]
# [('p', 'http://www.wikidata.org/prop/direct/P570'), ('name', 'date of death')]
# [('p', 'http://www.wikidata.org/prop/direct/P5731'), ('name', 'Angelicum ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5739'), ('name', 'Pontificia Università della Santa Croce ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5821'), ('name', 'ArhivX LOD')]
# [('p', 'http://www.wikidata.org/prop/direct/P5905'), ('name', 'Comic Vine ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6058'), ('name', 'Larousse ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P607'), ('name', 'conflict')]
# [('p', 'http://www.wikidata.org/prop/direct/P611'), ('name', 'religious order')]
# [('p', 'http://www.wikidata.org/prop/direct/P6173'), ('name', 'Bitraga author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6300'), ('name', 'Hymnary author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6327'), ('name', 'Goodreads character ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6379'), ('name', 'has works in the collection')]
# [('p', 'http://www.wikidata.org/prop/direct/P6394'), ('name', 'ELNET ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6403'), ('name', 'TheatreOnline ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6404'), ('name', "Treccani's Dizionario di Storia ID")]
# [('p', 'http://www.wikidata.org/prop/direct/P6412'), ('name', 'Gran Enciclopèdia de la Música ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P646'), ('name', 'Freebase ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P648'), ('name', 'Open Library ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P650'), ('name', 'RKDartists ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6573'), ('name', 'Klexikon article ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6578'), ('name', 'MutualArt artist ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6656'), ('name', 'BHCL ID (former scheme)')]
# [('p', 'http://www.wikidata.org/prop/direct/P6683'), ('name', 'Alexander Turnbull Library ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6745'), ('name', 'Orlando author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6764'), ('name', 'V&A person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6821'), ('name', 'Uppsala University Alvin ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6844'), ('name', 'abART person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6873'), ('name', 'IntraText author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6886'), ('name', 'writing language')]
# [('p', 'http://www.wikidata.org/prop/direct/P691'), ('name', 'NKCR AUT ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7024'), ('name', 'Flemish Public Libraries ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7026'), ('name', 'Lebanese National Library ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7029'), ('name', 'National Library of Russia ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7039'), ('name', 'National Library of Iceland ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7041'), ('name', 'Perseus author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7042'), ('name', 'The Latin Library author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7208'), ('name', 'Liber Liber author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7212'), ('name', 'LyricsTranslate ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P723'), ('name', 'Digitale Bibliotheek voor de Nederlandse Letteren author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7293'), ('name', 'PLWABN ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7311'), ('name', 'Aozora Bunko author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P734'), ('name', 'family name')]
# [('p', 'http://www.wikidata.org/prop/direct/P735'), ('name', 'given name')]
# [('p', 'http://www.wikidata.org/prop/direct/P7369'), ('name', 'National Library of Chile ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P737'), ('name', 'influenced by')]
# [('p', 'http://www.wikidata.org/prop/direct/P7388'), ('name', 'Great Encyclopedia of Navarre ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7400'), ('name', 'LibraryThing author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7433'), ('name', 'FantLab author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7444'), ('name', 'Rijksmuseum Research Library authority ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7507'), ('name', 'Ben Yehuda author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7666'), ('name', 'Visuotinė lietuvių enciklopedija ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7699'), ('name', 'National Library of Lithuania ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7700'), ('name', 'Slovak National Library ID (VIAF)')]
# [('p', 'http://www.wikidata.org/prop/direct/P7704'), ('name', 'Europeana entity')]
# [('p', 'http://www.wikidata.org/prop/direct/P7711'), ('name', 'Joconde author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7744'), ('name', 'Mille Anni di Scienza in Italia ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7753'), ('name', 'Projekt Gutenberg-DE ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7763'), ('name', 'copyright status as a creator')]
# [('p', 'http://www.wikidata.org/prop/direct/P7796'), ('name', 'BeWeb person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7818'), ('name', 'French Vikidia ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7822'), ('name', 'Italian Vikidia ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7859'), ('name', 'WorldCat Identities ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7865'), ('name', 'CoBiS author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7902'), ('name', 'Deutsche Biographie (GND) ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7929'), ('name', 'Roglo person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7935'), ('name', 'Corpus Corporum author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7982'), ('name', 'Hrvatska enciklopedija ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7986'), ('name', 'Mirabile author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7993'), ('name', "Treccani's Dizionario di Filosofia ID")]
# [('p', 'http://www.wikidata.org/prop/direct/P800'), ('name', 'notable work')]
# [('p', 'http://www.wikidata.org/prop/direct/P8034'), ('name', 'Vatican Library VcBA ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8122'), ('name', 'DLL Catalog author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8179'), ('name', 'Canadiana NCF ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8189'), ('name', 'National Library of Israel J9U ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8234'), ('name', 'LiederNet author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8248'), ('name', 'Colon Classification')]
# [('p', 'http://www.wikidata.org/prop/direct/P8287'), ('name', 'Worlds Without End author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8290'), ('name', 'Archivio Storico Ricordi person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8334'), ('name', 'MuseScore artist ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8349'), ('name', 'Proleksis enciklopedija ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8385'), ('name', 'IDU person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P839'), ('name', 'IMSLP ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8406'), ('name', 'Grove Art Online ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8440'), ('name', 'Personendatenbank Germania Sacra ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8496'), ('name', 'Archive Site Trinity College Cambridge ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8547'), ('name', 'BHF author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8568'), ('name', 'Jewish Virtual Library ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8625'), ('name', 'bibliography')]
# [('p', 'http://www.wikidata.org/prop/direct/P863'), ('name', 'InPhO ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8636'), ('name', 'McClintock and Strong Biblical Cyclopedia ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P866'), ('name', 'Perlentaucher ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8750'), ('name', 'Unione Romana Biblioteche Scientifiche ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8795'), ('name', 'General Diamond Catalogue ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8805'), ('name', 'LIMIS person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8814'), ('name', 'WordNet 3.1 Synset ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8826'), ('name', 'edition humboldt digital ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8833'), ('name', 'Union Catalog of Armenian Libraries authority ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8848'), ('name', 'CONOR.AL ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8849'), ('name', 'CONOR.BG ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8851'), ('name', 'CONOR.SR ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8885'), ('name', 'Namuwiki ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8899'), ('name', 'Swedish National Library Arken ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8902'), ('name', 'Archives at Yale names ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8947'), ('name', 'Museo Galileo authority ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8974'), ('name', 'SAPA ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8980'), ('name', 'KANTO ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P9000'), ('name', 'World History Encyclopedia ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P9017'), ('name', 'Medieval Manuscripts in Oxford Libraries person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P9037'), ('name', 'BHCL UUID')]
# [('p', 'http://www.wikidata.org/prop/direct/P906'), ('name', 'SELIBR ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P9081'), ('name', 'SEARCH on line catalogue ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P910'), ('name', "topic's main category")]
# [('p', 'http://www.wikidata.org/prop/direct/P9141'), ('name', 'Portal da Literatura ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P9164'), ('name', 'Svenska Institutet i Rom ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P9171'), ('name', 'RILM ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P9178'), ('name', 'Biblioteca Franco Serantini ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P9179'), ('name', 'Biblioteca Iglesia Nacional Española en Roma ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P9223'), ('name', 'Provenio UUID')]
# [('p', 'http://www.wikidata.org/prop/direct/P9226'), ('name', 'ARAE ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P9251'), ('name', 'Cyprus University of Technology ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P9282'), ('name', 'Catalogue of the Capitular Library of Verona author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P935'), ('name', 'Commons gallery')]
# [('p', 'http://www.wikidata.org/prop/direct/P9407'), ('name', 'Polignosi ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P949'), ('name', 'National Library of Israel ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P950'), ('name', 'Biblioteca Nacional de España ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P9507'), ('name', 'NBM authority ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P9522'), ('name', 'Biblioteca di Santa Sabina ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P9534'), ('name', 'Biblioteche della Custodia di Terra Santa a Gerusalemme ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P9536'), ('name', 'SAIA authority ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P9563'), ('name', 'Encyclopedia of Renaissance Philosophy ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P9626'), ('name', 'Biographical Encyclopedia of Astronomers ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P9653'), ('name', 'Bod-Inc Online author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P9661'), ('name', 'EBAF authority ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P9678'), ('name', 'Franciscan Center of Christian Oriental Studies ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P9756'), ('name', 'Schoenberg Database of Manuscripts name ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P9807'), ('name', 'SNK ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P4440'), ('name', 'Biblioteca Nacional de México ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7331'), ('name', 'Letteraturaitaliana.net author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P9575'), ('name', 'Australian Music Centre artist ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8603'), ('name', 'Istrapedia ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P9041'), ('name', 'DiVo person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P9642'), ('name', 'Olschki author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6583'), ('name', 'Lucerna person ID')]
# 298

# %%
# Get 'place of birth' and 'date of birth' of 'Dante Alighieri'
queryString = """
SELECT DISTINCT ?dob ?place ?placeName
WHERE {
   wd:Q1067 wdt:P569 ?dob .
   wd:Q1067 wdt:P19 ?place .
   # ?place sc:name ?placeName.
}
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('dob', '1265-01-01T00:00:00Z'), ('place', 'http://www.wikidata.org/entity/Q2044'), ('placeName', 'Florence')]
# 1

# %%
# Get all subjects that have 'poet' as 'occupation' that were born between 1300 and 1500 
queryString = """
SELECT DISTINCT ?poet ?name
WHERE {
   # ?poet wdt:P106 wd:Q49757 .
   # ?poet sc:name ?name.
   
   # ?poet wdt:P569 ?dob .
   FILTER (?dob >= "1300-01-01T00:00:00Z"^^xsd:dateTime && ?dob <= "1500-01-01T00:00:00Z"^^xsd:dateTime)
}
LIMIT 10
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('poet', 'http://www.wikidata.org/entity/Q16075667'), ('name', 'Du Mu')]
# [('poet', 'http://www.wikidata.org/entity/Q16039483'), ('name', 'Arias Barbosa')]
# [('poet', 'http://www.wikidata.org/entity/Q562300'), ('name', 'Gilles Joye')]
# [('poet', 'http://www.wikidata.org/entity/Q655618'), ('name', 'Francesco Berni')]
# [('poet', 'http://www.wikidata.org/entity/Q296272'), ('name', 'Pietro Aretino')]
# [('poet', 'http://www.wikidata.org/entity/Q5880389'), ('name', 'Girolamo Casio')]
# [('poet', 'http://www.wikidata.org/entity/Q21003797'), ('name', 'Michel Verin')]
# [('poet', 'http://www.wikidata.org/entity/Q22586308'), ('name', 'Domenico da Prato')]
# [('poet', 'http://www.wikidata.org/entity/Q790956'), ('name', 'Avigdor Kara')]
# [('poet', 'http://www.wikidata.org/entity/Q7141661'), ('name', 'Kakimon-in')]
# 10

# %%
# Get all subjects that have 'poet' as 'occupation' that were born between 1300 and 1500 and born in 'Florence'
queryString = """
SELECT DISTINCT ?poet ?name
WHERE {
   # ?poet wdt:P106 wd:Q49757 .
   # ?poet sc:name ?name.
   
   # ?poet wdt:P569 ?dob .
   FILTER (?dob >= "1300-01-01T00:00:00Z"^^xsd:dateTime && ?dob <= "1500-01-01T00:00:00Z"^^xsd:dateTime)
   
   # ?poet wdt:P19 ?place .
   FILTER(?place = wd:Q2044)
}
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('poet', 'http://www.wikidata.org/entity/Q21003797'), ('name', 'Michel Verin')]
# [('poet', 'http://www.wikidata.org/entity/Q1248954'), ('name', 'Giovanni di Bernardo Rucellai')]
# [('poet', 'http://www.wikidata.org/entity/Q177854'), ('name', "Lorenzo de' Medici")]
# [('poet', 'http://www.wikidata.org/entity/Q328117'), ('name', 'Girolamo Benivieni')]
# [('poet', 'http://www.wikidata.org/entity/Q721846'), ('name', 'Luigi Alamanni')]
# [('poet', 'http://www.wikidata.org/entity/Q1399'), ('name', 'Niccolò Machiavelli')]
# [('poet', 'http://www.wikidata.org/entity/Q366499'), ('name', 'Orcagna')]
# [('poet', 'http://www.wikidata.org/entity/Q1402'), ('name', 'Giovanni Boccaccio')]
# [('poet', 'http://www.wikidata.org/entity/Q631635'), ('name', 'Luigi Pulci')]
# [('poet', 'http://www.wikidata.org/entity/Q2857170'), ('name', 'Antonio Alamanni')]
# [('poet', 'http://www.wikidata.org/entity/Q1527917'), ('name', 'Giuliano Dati')]
# [('poet', 'http://www.wikidata.org/entity/Q45539848'), ('name', 'Niccolò Tinucci')]
# [('poet', 'http://www.wikidata.org/entity/Q1113645'), ('name', 'Lucrezia Tornabuoni')]
# [('poet', 'http://www.wikidata.org/entity/Q711964'), ('name', 'Cristoforo Landino')]
# [('poet', 'http://www.wikidata.org/entity/Q741841'), ('name', 'Ugolino di Vieri')]
# [('poet', 'http://www.wikidata.org/entity/Q3677259'), ('name', 'Cino Rinuccini')]
# [('poet', 'http://www.wikidata.org/entity/Q640594'), ('name', 'John Dominici')]
# [('poet', 'http://www.wikidata.org/entity/Q781511'), ('name', 'Aurelio Lippo Brandolini')]
# [('poet', 'http://www.wikidata.org/entity/Q13570581'), ('name', 'Bartolomeo della Fonte')]
# [('poet', 'http://www.wikidata.org/entity/Q302218'), ('name', 'Agnolo Firenzuola')]
# [('poet', 'http://www.wikidata.org/entity/Q62055718'), ('name', "Lippo Pasci de' Bardi")]
# [('poet', 'http://www.wikidata.org/entity/Q425969'), ('name', 'Bernardo Bellincioni')]
# [('poet', 'http://www.wikidata.org/entity/Q1229872'), ('name', 'Matteo Palmieri')]
# [('poet', 'http://www.wikidata.org/entity/Q589545'), ('name', 'Bernardo Pulci')]
# [('poet', 'http://www.wikidata.org/entity/Q1215784'), ('name', 'Alessandra Scala')]
# [('poet', 'http://www.wikidata.org/entity/Q659093'), ('name', 'Benedetto Dei')]
# [('poet', 'http://www.wikidata.org/entity/Q50399164'), ('name', "Dolcibene de' Tori")]
# [('poet', 'http://www.wikidata.org/entity/Q1149308'), ('name', 'Rustico Filippi')]
# [('poet', 'http://www.wikidata.org/entity/Q3830353'), ('name', 'Leonardo Dati')]
# [('poet', 'http://www.wikidata.org/entity/Q66809563'), ('name', "Alessandro Pazzi de' Medici")]
# [('poet', 'http://www.wikidata.org/entity/Q604448'), ('name', 'Antonio Pucci')]
# [('poet', 'http://www.wikidata.org/entity/Q2832756'), ('name', 'Alessandro Braccesi')]
# [('poet', 'http://www.wikidata.org/entity/Q3750836'), ('name', "Francesco d'Altobianco Alberti")]
# [('poet', 'http://www.wikidata.org/entity/Q1058842'), ('name', 'Domenico di Giovanni')]
# [('poet', 'http://www.wikidata.org/entity/Q1158784'), ('name', 'Crinitus')]
# [('poet', 'http://www.wikidata.org/entity/Q17166727'), ('name', 'Antonio di Meglio')]
# [('poet', 'http://www.wikidata.org/entity/Q15633606'), ('name', 'Bondie Dietaiuti')]
# [('poet', 'http://www.wikidata.org/entity/Q3339583'), ('name', 'Niccolò Martelli')]
# [('poet', 'http://www.wikidata.org/entity/Q3763435'), ('name', 'Gianni Alfani')]
# [('poet', 'http://www.wikidata.org/entity/Q3068447'), ('name', 'Feo Belcari')]
# [('poet', 'http://www.wikidata.org/entity/Q18945288'), ('name', 'Francesco da Firenze')]
# 41

# %% [markdown]
# Final query for this task

# %%
# Get all subjects that have 'poet' as 'occupation' that were born between 1300 (included) and 1500 (included) and born in 'Florence'
queryString = """
SELECT DISTINCT ?poet ?name
WHERE {
   # ?poet wdt:P106 wd:Q49757 .
   # ?poet sc:name ?name.
   
   # ?poet wdt:P569 ?dob .
   FILTER (?dob >= "1300-01-01T00:00:00Z"^^xsd:dateTime && ?dob <= "1500-12-31T23:59:59Z"^^xsd:dateTime)
   
   # ?poet wdt:P19 ?place .
   FILTER(?place = wd:Q2044)
}
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('poet', 'http://www.wikidata.org/entity/Q21003797'), ('name', 'Michel Verin')]
# [('poet', 'http://www.wikidata.org/entity/Q1248954'), ('name', 'Giovanni di Bernardo Rucellai')]
# [('poet', 'http://www.wikidata.org/entity/Q177854'), ('name', "Lorenzo de' Medici")]
# [('poet', 'http://www.wikidata.org/entity/Q328117'), ('name', 'Girolamo Benivieni')]
# [('poet', 'http://www.wikidata.org/entity/Q721846'), ('name', 'Luigi Alamanni')]
# [('poet', 'http://www.wikidata.org/entity/Q1399'), ('name', 'Niccolò Machiavelli')]
# [('poet', 'http://www.wikidata.org/entity/Q366499'), ('name', 'Orcagna')]
# [('poet', 'http://www.wikidata.org/entity/Q1402'), ('name', 'Giovanni Boccaccio')]
# [('poet', 'http://www.wikidata.org/entity/Q631635'), ('name', 'Luigi Pulci')]
# [('poet', 'http://www.wikidata.org/entity/Q2857170'), ('name', 'Antonio Alamanni')]
# [('poet', 'http://www.wikidata.org/entity/Q1527917'), ('name', 'Giuliano Dati')]
# [('poet', 'http://www.wikidata.org/entity/Q45539848'), ('name', 'Niccolò Tinucci')]
# [('poet', 'http://www.wikidata.org/entity/Q1113645'), ('name', 'Lucrezia Tornabuoni')]
# [('poet', 'http://www.wikidata.org/entity/Q711964'), ('name', 'Cristoforo Landino')]
# [('poet', 'http://www.wikidata.org/entity/Q741841'), ('name', 'Ugolino di Vieri')]
# [('poet', 'http://www.wikidata.org/entity/Q3677259'), ('name', 'Cino Rinuccini')]
# [('poet', 'http://www.wikidata.org/entity/Q640594'), ('name', 'John Dominici')]
# [('poet', 'http://www.wikidata.org/entity/Q781511'), ('name', 'Aurelio Lippo Brandolini')]
# [('poet', 'http://www.wikidata.org/entity/Q13570581'), ('name', 'Bartolomeo della Fonte')]
# [('poet', 'http://www.wikidata.org/entity/Q302218'), ('name', 'Agnolo Firenzuola')]
# [('poet', 'http://www.wikidata.org/entity/Q62055718'), ('name', "Lippo Pasci de' Bardi")]
# [('poet', 'http://www.wikidata.org/entity/Q19357719'), ('name', 'Lodovico Martelli')]
# [('poet', 'http://www.wikidata.org/entity/Q425969'), ('name', 'Bernardo Bellincioni')]
# [('poet', 'http://www.wikidata.org/entity/Q1229872'), ('name', 'Matteo Palmieri')]
# [('poet', 'http://www.wikidata.org/entity/Q589545'), ('name', 'Bernardo Pulci')]
# [('poet', 'http://www.wikidata.org/entity/Q1215784'), ('name', 'Alessandra Scala')]
# [('poet', 'http://www.wikidata.org/entity/Q659093'), ('name', 'Benedetto Dei')]
# [('poet', 'http://www.wikidata.org/entity/Q50399164'), ('name', "Dolcibene de' Tori")]
# [('poet', 'http://www.wikidata.org/entity/Q1149308'), ('name', 'Rustico Filippi')]
# [('poet', 'http://www.wikidata.org/entity/Q3830353'), ('name', 'Leonardo Dati')]
# [('poet', 'http://www.wikidata.org/entity/Q66809563'), ('name', "Alessandro Pazzi de' Medici")]
# [('poet', 'http://www.wikidata.org/entity/Q604448'), ('name', 'Antonio Pucci')]
# [('poet', 'http://www.wikidata.org/entity/Q2832756'), ('name', 'Alessandro Braccesi')]
# [('poet', 'http://www.wikidata.org/entity/Q3750836'), ('name', "Francesco d'Altobianco Alberti")]
# [('poet', 'http://www.wikidata.org/entity/Q1058842'), ('name', 'Domenico di Giovanni')]
# [('poet', 'http://www.wikidata.org/entity/Q1158784'), ('name', 'Crinitus')]
# [('poet', 'http://www.wikidata.org/entity/Q17166727'), ('name', 'Antonio di Meglio')]
# [('poet', 'http://www.wikidata.org/entity/Q15633606'), ('name', 'Bondie Dietaiuti')]
# [('poet', 'http://www.wikidata.org/entity/Q3339583'), ('name', 'Niccolò Martelli')]
# [('poet', 'http://www.wikidata.org/entity/Q3763435'), ('name', 'Gianni Alfani')]
# [('poet', 'http://www.wikidata.org/entity/Q3068447'), ('name', 'Feo Belcari')]
# [('poet', 'http://www.wikidata.org/entity/Q18945288'), ('name', 'Francesco da Firenze')]
# 42

# %% [markdown]
# ## Task 5
# Identify the BGP for literary work

# %%
# Get informations about 'instance of' property of 'The Divine Commedy'
queryString = """
SELECT DISTINCT ?o ?name
WHERE {
   wd:Q40185 wdt:P31 ?o .
   # ?o sc:name ?name.
}
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('o', 'http://www.wikidata.org/entity/Q47461344'), ('name', 'written work')]
# 1

# %%
# Get properties of 'written work'
queryString = """
SELECT DISTINCT ?p ?name
WHERE {
   wd:Q47461344 ?p ?o .
   # ?p sc:name ?name.
}
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P1889'), ('name', 'different from')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('name', 'properties for this type')]
# [('p', 'http://www.wikidata.org/prop/direct/P2283'), ('name', 'uses')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('name', 'subclass of')]
# [('p', 'http://www.wikidata.org/prop/direct/P460'), ('name', 'said to be the same as')]
# [('p', 'http://www.wikidata.org/prop/direct/P8408'), ('name', 'KBpedia ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P910'), ('name', "topic's main category")]
# 7

# %%
# Get superclass of 'written work'
queryString = """
SELECT DISTINCT ?super ?name
WHERE {
   wd:Q47461344 wdt:P279 ?super .
   # ?super sc:name ?name.
}
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('super', 'http://www.wikidata.org/entity/Q17537576'), ('name', 'creative work')]
# 1

# %%
# Get all instances of 'written work'
queryString = """
SELECT DISTINCT ?inst ?name
WHERE {
   # ?inst wdt:P279 wd:Q47461344 .
   # ?inst sc:name ?name.
}
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('inst', 'http://www.wikidata.org/entity/Q1433985'), ('name', 'broadside')]
# [('inst', 'http://www.wikidata.org/entity/Q58901591'), ('name', 'comparative study')]
# [('inst', 'http://www.wikidata.org/entity/Q7254446'), ('name', 'pseudo-scholarship')]
# [('inst', 'http://www.wikidata.org/entity/Q1501855'), ('name', 'party platform')]
# [('inst', 'http://www.wikidata.org/entity/Q58898636'), ('name', 'evaluation study')]
# [('inst', 'http://www.wikidata.org/entity/Q277759'), ('name', 'book series')]
# [('inst', 'http://www.wikidata.org/entity/Q7397'), ('name', 'software')]
# [('inst', 'http://www.wikidata.org/entity/Q7725634'), ('name', 'literary work')]
# [('inst', 'http://www.wikidata.org/entity/Q13136'), ('name', 'reference work')]
# [('inst', 'http://www.wikidata.org/entity/Q15087423'), ('name', 'ISO standard')]
# [('inst', 'http://www.wikidata.org/entity/Q2352616'), ('name', 'catalogue')]
# [('inst', 'http://www.wikidata.org/entity/Q5173771'), ('name', 'brochure')]
# [('inst', 'http://www.wikidata.org/entity/Q591041'), ('name', 'scientific publication')]
# [('inst', 'http://www.wikidata.org/entity/Q571'), ('name', 'book')]
# [('inst', 'http://www.wikidata.org/entity/Q1002697'), ('name', 'periodical')]
# [('inst', 'http://www.wikidata.org/entity/Q191067'), ('name', 'article')]
# [('inst', 'http://www.wikidata.org/entity/Q669777'), ('name', 'epigraph')]
# [('inst', 'http://www.wikidata.org/entity/Q63994109'), ('name', 'wine guide')]
# [('inst', 'http://www.wikidata.org/entity/Q55915575'), ('name', 'scholarly work')]
# [('inst', 'http://www.wikidata.org/entity/Q3594128'), ('name', 'collective work')]
# 20

# %% [markdown]
# Final query for this task

# %%
queryString = """
SELECT DISTINCT ?inst ?name
WHERE {
   # ?inst wdt:P279 wd:Q47461344 .
   # ?inst sc:name ?name.
   FILTER REGEX (?name, "literary work")
}
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('inst', 'http://www.wikidata.org/entity/Q7725634'), ('name', 'literary work')]
# 1

# %% [markdown]
# ## Task 6
# Compare the author of The Divine Comedy with Giovanni Boccaccio. Return for these poets the number of literary work they wrote (the result set must be two triples -one for each author- author IRI, label and #literary work).

# %%
# Get the properties of 'Human'
queryString = """
SELECT DISTINCT ?p ?name
WHERE {
   wd:Q5 ?p ?obj .
   # ?p sc:name ?name.
}
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P5806'), ('name', 'SNOMED CT identifier')]
# [('p', 'http://www.wikidata.org/prop/direct/P1036'), ('name', 'Dewey Decimal Classification')]
# [('p', 'http://www.wikidata.org/prop/direct/P1051'), ('name', 'PSH ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1056'), ('name', 'product or material produced')]
# [('p', 'http://www.wikidata.org/prop/direct/P1225'), ('name', 'U.S. National Archives Identifier')]
# [('p', 'http://www.wikidata.org/prop/direct/P1245'), ('name', 'OmegaWiki Defined Meaning')]
# [('p', 'http://www.wikidata.org/prop/direct/P1256'), ('name', 'Iconclass notation')]
# [('p', 'http://www.wikidata.org/prop/direct/P129'), ('name', 'physically interacts with')]
# [('p', 'http://www.wikidata.org/prop/direct/P1296'), ('name', 'Gran Enciclopèdia Catalana ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1343'), ('name', 'described by source')]
# [('p', 'http://www.wikidata.org/prop/direct/P1417'), ('name', 'Encyclopædia Britannica Online ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1424'), ('name', "topic's main template")]
# [('p', 'http://www.wikidata.org/prop/direct/P1542'), ('name', 'has effect')]
# [('p', 'http://www.wikidata.org/prop/direct/P1552'), ('name', 'has quality')]
# [('p', 'http://www.wikidata.org/prop/direct/P1709'), ('name', 'equivalent class')]
# [('p', 'http://www.wikidata.org/prop/direct/P1748'), ('name', 'NCI Thesaurus ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P18'), ('name', 'image')]
# [('p', 'http://www.wikidata.org/prop/direct/P1889'), ('name', 'different from')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('name', 'properties for this type')]
# [('p', 'http://www.wikidata.org/prop/direct/P227'), ('name', 'GND ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2283'), ('name', 'uses')]
# [('p', 'http://www.wikidata.org/prop/direct/P2579'), ('name', 'studied by')]
# [('p', 'http://www.wikidata.org/prop/direct/P2581'), ('name', 'BabelNet ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2670'), ('name', 'has parts of the class')]
# [('p', 'http://www.wikidata.org/prop/direct/P268'), ('name', 'Bibliothèque nationale de France ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('name', 'subclass of')]
# [('p', 'http://www.wikidata.org/prop/direct/P2888'), ('name', 'exact match')]
# [('p', 'http://www.wikidata.org/prop/direct/P2892'), ('name', 'UMLS CUI')]
# [('p', 'http://www.wikidata.org/prop/direct/P2959'), ('name', 'permanent duplicated item')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('name', 'instance of')]
# [('p', 'http://www.wikidata.org/prop/direct/P3222'), ('name', 'NE.se ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3241'), ('name', 'Catholic Encyclopedia ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3417'), ('name', 'Quora topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3553'), ('name', 'Zhihu topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P361'), ('name', 'part of')]
# [('p', 'http://www.wikidata.org/prop/direct/P373'), ('name', 'Commons category')]
# [('p', 'http://www.wikidata.org/prop/direct/P3827'), ('name', 'JSTOR topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3916'), ('name', 'UNESCO Thesaurus ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P425'), ('name', 'field of this occupation')]
# [('p', 'http://www.wikidata.org/prop/direct/P443'), ('name', 'pronunciation audio')]
# [('p', 'http://www.wikidata.org/prop/direct/P460'), ('name', 'said to be the same as')]
# [('p', 'http://www.wikidata.org/prop/direct/P4613'), ('name', 'Encyclopedia of Modern Ukraine ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P4733'), ('name', 'produced sound')]
# [('p', 'http://www.wikidata.org/prop/direct/P486'), ('name', 'MeSH descriptor ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5008'), ('name', 'on focus list of Wikimedia project')]
# [('p', 'http://www.wikidata.org/prop/direct/P5198'), ('name', 'ASC Leiden Thesaurus ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5247'), ('name', 'Giant Bomb ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('name', 'has part')]
# [('p', 'http://www.wikidata.org/prop/direct/P5555'), ('name', 'schematic')]
# [('p', 'http://www.wikidata.org/prop/direct/P5869'), ('name', 'model item')]
# [('p', 'http://www.wikidata.org/prop/direct/P6332'), ('name', "Panorama de l'art ID")]
# [('p', 'http://www.wikidata.org/prop/direct/P6385'), ('name', 'Krugosvet article')]
# [('p', 'http://www.wikidata.org/prop/direct/P646'), ('name', 'Freebase ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6573'), ('name', 'Klexikon article ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P672'), ('name', 'MeSH tree code')]
# [('p', 'http://www.wikidata.org/prop/direct/P6839'), ('name', 'TV Tropes identifier')]
# [('p', 'http://www.wikidata.org/prop/direct/P6900'), ('name', 'NicoNicoPedia ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7007'), ('name', 'Wolfram Language unit code')]
# [('p', 'http://www.wikidata.org/prop/direct/P7033'), ('name', 'Australian Educational Vocabulary ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7314'), ('name', 'TDV İslam Ansiklopedisi ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7329'), ('name', 'ICD-11 ID (MMS)')]
# [('p', 'http://www.wikidata.org/prop/direct/P7497'), ('name', 'Wolfram Language entity type')]
# [('p', 'http://www.wikidata.org/prop/direct/P7703'), ('name', 'Spanish Quora topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7807'), ('name', 'ICD-11 (foundation)')]
# [('p', 'http://www.wikidata.org/prop/direct/P8168'), ('name', 'FactGrid item ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8408'), ('name', 'KBpedia ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8419'), ('name', 'Archive of Our Own tag')]
# [('p', 'http://www.wikidata.org/prop/direct/P8785'), ('name', 'AniDB tag ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8885'), ('name', 'Namuwiki ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8895'), ('name', 'All the Tropes identifier')]
# [('p', 'http://www.wikidata.org/prop/direct/P8972'), ('name', 'small logo or icon')]
# [('p', 'http://www.wikidata.org/prop/direct/P910'), ('name', "topic's main category")]
# [('p', 'http://www.wikidata.org/prop/direct/P949'), ('name', 'National Library of Israel ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8512'), ('name', 'size comparison diagram')]
# 74

# %%
# Filter among 'Humans' people with name 'Giovanni ...' and surname 'Boccaccio'
queryString = """
SELECT DISTINCT ?human ?surname ?firstname
WHERE {
    # ?human wdt:P31 wd:Q5. 
    # ?human wdt:P734 ?familyName .
    # ?familyName sc:name ?surname.
    
    FILTER REGEX(?surname,"^[Bb]occaccio")
    
    # ?human wdt:P735 ?givenName .
    # ?givenName sc:name ?firstname.
    FILTER REGEX(?firstname,"^[Gg]iovanni*")
    
}
LIMIT 10
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('human', 'http://www.wikidata.org/entity/Q3766842'), ('surname', 'Boccaccio'), ('firstname', 'Giovanni')]
# [('human', 'http://www.wikidata.org/entity/Q1402'), ('surname', 'Boccaccio'), ('firstname', 'Giovanni')]
# 2

# %%
# Filter among 'Humans' people with name 'Giovanni ...' and surname 'Boccaccio'
queryString = """
SELECT DISTINCT ?human ?surname ?firstname
WHERE {
    # ?human wdt:P31 wd:Q5. 
    # ?human wdt:P734 ?familyName .
    # ?familyName sc:name ?surname.
    
    FILTER REGEX(?surname,"^[Bb]occaccio")
    
    # ?human wdt:P735 ?givenName .
    # ?givenName sc:name ?firstname.
    FILTER REGEX(?firstname,"^[Gg]iovanni*")
    
}
LIMIT 10
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('human', 'http://www.wikidata.org/entity/Q3766842'), ('surname', 'Boccaccio'), ('firstname', 'Giovanni')]
# [('human', 'http://www.wikidata.org/entity/Q1402'), ('surname', 'Boccaccio'), ('firstname', 'Giovanni')]
# 2

# %%
# Filter among 'Humans' people with name 'Giovanni ...' and surname 'Boccaccio' and get the occupation of matches
queryString = """
SELECT DISTINCT ?human ?surname ?firstname ?occupationName
WHERE {
    # ?human wdt:P31 wd:Q5. 
    
    # ?human wdt:P734 ?familyName .
    # ?familyName sc:name ?surname.
    FILTER REGEX(?surname,"^[Bb]occaccio")
    
    # ?human wdt:P735 ?givenName .
    # ?givenName sc:name ?firstname.
    FILTER REGEX(?firstname,"^[Gg]iovanni*")
    
    # ?human wdt:P106 ?occupation .
    # ?occupation sc:name ?occupationName.
}
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('human', 'http://www.wikidata.org/entity/Q3766842'), ('surname', 'Boccaccio'), ('firstname', 'Giovanni'), ('occupationName', 'carabinier')]
# [('human', 'http://www.wikidata.org/entity/Q1402'), ('surname', 'Boccaccio'), ('firstname', 'Giovanni'), ('occupationName', 'short story writer')]
# [('human', 'http://www.wikidata.org/entity/Q1402'), ('surname', 'Boccaccio'), ('firstname', 'Giovanni'), ('occupationName', 'diplomat')]
# [('human', 'http://www.wikidata.org/entity/Q1402'), ('surname', 'Boccaccio'), ('firstname', 'Giovanni'), ('occupationName', 'translator')]
# [('human', 'http://www.wikidata.org/entity/Q1402'), ('surname', 'Boccaccio'), ('firstname', 'Giovanni'), ('occupationName', 'writer')]
# [('human', 'http://www.wikidata.org/entity/Q1402'), ('surname', 'Boccaccio'), ('firstname', 'Giovanni'), ('occupationName', 'poet')]
# [('human', 'http://www.wikidata.org/entity/Q1402'), ('surname', 'Boccaccio'), ('firstname', 'Giovanni'), ('occupationName', 'biographer')]
# [('human', 'http://www.wikidata.org/entity/Q1402'), ('surname', 'Boccaccio'), ('firstname', 'Giovanni'), ('occupationName', 'mythographer')]
# 8

# %%
# Filter among 'Humans' people with name 'Giovanni ...' and surname 'Boccaccio' and have occupation 'Poet'
queryString = """
SELECT DISTINCT ?human ?surname ?firstname
WHERE {
    # ?human wdt:P31 wd:Q5. 
    
    # ?human wdt:P734 ?familyName .
    # ?familyName sc:name ?surname.
    FILTER REGEX(?surname,"^[Bb]occaccio")
    
    # ?human wdt:P735 ?givenName .
    # ?givenName sc:name ?firstname.
    FILTER REGEX(?firstname,"^[Gg]iovanni*")
    
    # ?human wdt:P106 ?occupation .
    FILTER(?occupation = wd:Q49757)
}
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('human', 'http://www.wikidata.org/entity/Q1402'), ('surname', 'Boccaccio'), ('firstname', 'Giovanni')]
# 1

# %%
# get all properties of 'Giovanni Boccaccio'
queryString = """
SELECT DISTINCT ?p ?name
WHERE {
   wd:Q1402 ?p ?obj .
   # ?p sc:name ?name.
}
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P2018'), ('name', 'Teuchos ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7992'), ('name', "Poeti d'Italia in lingua latina author ID")]
# [('p', 'http://www.wikidata.org/prop/direct/P8975'), ('name', 'Manus Online author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1005'), ('name', 'Portuguese National Library ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1006'), ('name', 'Nationale Thesaurus voor Auteurs ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1015'), ('name', 'NORAF ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1017'), ('name', 'Vatican Library ID (former scheme)')]
# [('p', 'http://www.wikidata.org/prop/direct/P103'), ('name', 'native language')]
# [('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('p', 'http://www.wikidata.org/prop/direct/P1066'), ('name', 'student of')]
# [('p', 'http://www.wikidata.org/prop/direct/P1150'), ('name', 'Regensburg Classification')]
# [('p', 'http://www.wikidata.org/prop/direct/P119'), ('name', 'place of burial')]
# [('p', 'http://www.wikidata.org/prop/direct/P1207'), ('name', 'NUKAT ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1220'), ('name', 'Internet Broadway Database person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1233'), ('name', 'Internet Speculative Fiction Database author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1263'), ('name', 'NNDB people ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1266'), ('name', 'AlloCiné person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1273'), ('name', 'CANTIC ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1280'), ('name', 'CONOR.SI ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1296'), ('name', 'Gran Enciclopèdia Catalana ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1309'), ('name', 'EGAXA ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1315'), ('name', 'NLA Trove ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1343'), ('name', 'described by source')]
# [('p', 'http://www.wikidata.org/prop/direct/P1368'), ('name', 'LNB ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1375'), ('name', 'NSK ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1412'), ('name', 'languages spoken, written or signed')]
# [('p', 'http://www.wikidata.org/prop/direct/P1417'), ('name', 'Encyclopædia Britannica Online ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1422'), ('name', 'Sandrart.net person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1424'), ('name', "topic's main template")]
# [('p', 'http://www.wikidata.org/prop/direct/P1472'), ('name', 'Commons Creator page')]
# [('p', 'http://www.wikidata.org/prop/direct/P1580'), ('name', 'University of Barcelona authority ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1695'), ('name', 'NLP ID (unique)')]
# [('p', 'http://www.wikidata.org/prop/direct/P1711'), ('name', 'British Museum person or institution ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P172'), ('name', 'ethnic group')]
# [('p', 'http://www.wikidata.org/prop/direct/P18'), ('name', 'image')]
# [('p', 'http://www.wikidata.org/prop/direct/P1871'), ('name', 'CERL Thesaurus ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1890'), ('name', 'CCAB ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1899'), ('name', 'LibriVox author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P19'), ('name', 'place of birth')]
# [('p', 'http://www.wikidata.org/prop/direct/P1938'), ('name', 'Project Gutenberg author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1953'), ('name', 'Discogs artist ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1977'), ('name', 'Les Archives du Spectacle Person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1986'), ('name', 'Biographical Dictionary of Italian People ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P20'), ('name', 'place of death')]
# [('p', 'http://www.wikidata.org/prop/direct/P2019'), ('name', 'AllMovie person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P21'), ('name', 'sex or gender')]
# [('p', 'http://www.wikidata.org/prop/direct/P213'), ('name', 'ISNI')]
# [('p', 'http://www.wikidata.org/prop/direct/P214'), ('name', 'VIAF ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2163'), ('name', 'FAST ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2168'), ('name', 'Swedish Film Database person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2188'), ('name', 'BiblioNet author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2191'), ('name', 'Vegetti Catalog of Fantastic Literature NILF ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2252'), ('name', 'National Gallery of Art artist ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P227'), ('name', 'GND ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2435'), ('name', 'PORT person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P244'), ('name', 'Library of Congress authority ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P245'), ('name', 'Union List of Artist Names ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2469'), ('name', 'Theatricalia person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2510'), ('name', 'National Discography of Italian Song artist/group ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2600'), ('name', 'Geni.com profile ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2604'), ('name', 'Kinopoisk person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2605'), ('name', 'ČSFD person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2639'), ('name', 'Filmportal ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P268'), ('name', 'Bibliothèque nationale de France ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P269'), ('name', 'IdRef ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P27'), ('name', 'country of citizenship')]
# [('p', 'http://www.wikidata.org/prop/direct/P271'), ('name', 'CiNii author ID (books)')]
# [('p', 'http://www.wikidata.org/prop/direct/P2734'), ('name', 'Unz Review author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2799'), ('name', 'BVMC person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2886'), ('name', 'Shakeosphere person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2924'), ('name', 'Great Russian Encyclopedia Online ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2963'), ('name', 'Goodreads author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2966'), ('name', 'National Library of Wales Authority ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2977'), ('name', 'LBT person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3065'), ('name', 'RERO ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('name', 'instance of')]
# [('p', 'http://www.wikidata.org/prop/direct/P3126'), ('name', 'ALCUIN ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3154'), ('name', 'Runeberg author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3219'), ('name', 'Encyclopædia Universalis ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3222'), ('name', 'NE.se ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3241'), ('name', 'Catholic Encyclopedia ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3280'), ('name', 'BAnQ author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3342'), ('name', 'significant person')]
# [('p', 'http://www.wikidata.org/prop/direct/P3348'), ('name', 'National Library of Greece ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3365'), ('name', 'Treccani ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3417'), ('name', 'Quora topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3430'), ('name', 'SNAC ARK ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P345'), ('name', 'IMDb ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P349'), ('name', 'National Diet Library ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3569'), ('name', 'Cultureel Woordenboek ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3630'), ('name', 'Babelio author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P373'), ('name', 'Commons category')]
# [('p', 'http://www.wikidata.org/prop/direct/P3762'), ('name', 'openMLOL author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3788'), ('name', 'BNMM authority ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3846'), ('name', 'DBC author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P396'), ('name', 'SBN author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3980'), ('name', 'Unifrance person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3987'), ('name', 'SHARE Catalogue author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P409'), ('name', 'Libraries Australia ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P4200'), ('name', "Christie's creator ID")]
# [('p', 'http://www.wikidata.org/prop/direct/P4223'), ('name', "Treccani's Enciclopedia Italiana ID")]
# [('p', 'http://www.wikidata.org/prop/direct/P434'), ('name', 'MusicBrainz artist ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P4342'), ('name', 'Store norske leksikon ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P4343'), ('name', 'WBPLN author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P4399'), ('name', 'Itaú Cultural ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P4491'), ('name', 'Isidore scholar ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P4549'), ('name', 'ARLIMA ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P4619'), ('name', 'National Library of Brazil ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P4629'), ('name', 'Online Books Page author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P4839'), ('name', 'Wolfram Language entity code')]
# [('p', 'http://www.wikidata.org/prop/direct/P4985'), ('name', 'TMDb person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5002'), ('name', 'Orthodox Encyclopedia ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5019'), ('name', 'Brockhaus Enzyklopädie online ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5034'), ('name', 'National Library of Korea ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5063'), ('name', 'Interlingual Index ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P509'), ('name', 'cause of death')]
# [('p', 'http://www.wikidata.org/prop/direct/P5343'), ('name', 'Poets.org poet ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P535'), ('name', 'Find A Grave memorial ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5361'), ('name', 'BNB person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5492'), ('name', 'EDIT16 catalogue author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5504'), ('name', 'RISM ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5570'), ('name', 'NooSFere author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5587'), ('name', 'Libris-URI')]
# [('p', 'http://www.wikidata.org/prop/direct/P5613'), ('name', 'Bibliothèque de la Pléiade ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P569'), ('name', 'date of birth')]
# [('p', 'http://www.wikidata.org/prop/direct/P570'), ('name', 'date of death')]
# [('p', 'http://www.wikidata.org/prop/direct/P5731'), ('name', 'Angelicum ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5739'), ('name', 'Pontificia Università della Santa Croce ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5821'), ('name', 'ArhivX LOD')]
# [('p', 'http://www.wikidata.org/prop/direct/P5905'), ('name', 'Comic Vine ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5964'), ('name', 'Norwegian Nationaltheatret actor ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6058'), ('name', 'Larousse ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6173'), ('name', 'Bitraga author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6327'), ('name', 'Goodreads character ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6379'), ('name', 'has works in the collection')]
# [('p', 'http://www.wikidata.org/prop/direct/P6394'), ('name', 'ELNET ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P646'), ('name', 'Freebase ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P648'), ('name', 'Open Library ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P650'), ('name', 'RKDartists ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6656'), ('name', 'BHCL ID (former scheme)')]
# [('p', 'http://www.wikidata.org/prop/direct/P6683'), ('name', 'Alexander Turnbull Library ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6745'), ('name', 'Orlando author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6764'), ('name', 'V&A person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6844'), ('name', 'abART person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6873'), ('name', 'IntraText author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6886'), ('name', 'writing language')]
# [('p', 'http://www.wikidata.org/prop/direct/P691'), ('name', 'NKCR AUT ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7026'), ('name', 'Lebanese National Library ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7029'), ('name', 'National Library of Russia ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7157'), ('name', 'The Top Tens ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7208'), ('name', 'Liber Liber author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7212'), ('name', 'LyricsTranslate ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P723'), ('name', 'Digitale Bibliotheek voor de Nederlandse Letteren author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7293'), ('name', 'PLWABN ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P734'), ('name', 'family name')]
# [('p', 'http://www.wikidata.org/prop/direct/P735'), ('name', 'given name')]
# [('p', 'http://www.wikidata.org/prop/direct/P7369'), ('name', 'National Library of Chile ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7444'), ('name', 'Rijksmuseum Research Library authority ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7580'), ('name', 'Ala Bahrami')]
# [('p', 'http://www.wikidata.org/prop/direct/P7666'), ('name', 'Visuotinė lietuvių enciklopedija ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7699'), ('name', 'National Library of Lithuania ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7704'), ('name', 'Europeana entity')]
# [('p', 'http://www.wikidata.org/prop/direct/P7753'), ('name', 'Projekt Gutenberg-DE ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7763'), ('name', 'copyright status as a creator')]
# [('p', 'http://www.wikidata.org/prop/direct/P7796'), ('name', 'BeWeb person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7818'), ('name', 'French Vikidia ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7832'), ('name', 'Basque Vikidia ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7859'), ('name', 'WorldCat Identities ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7865'), ('name', 'CoBiS author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7902'), ('name', 'Deutsche Biographie (GND) ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7935'), ('name', 'Corpus Corporum author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7982'), ('name', 'Hrvatska enciklopedija ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7986'), ('name', 'Mirabile author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P800'), ('name', 'notable work')]
# [('p', 'http://www.wikidata.org/prop/direct/P802'), ('name', 'student')]
# [('p', 'http://www.wikidata.org/prop/direct/P8034'), ('name', 'Vatican Library VcBA ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8122'), ('name', 'DLL Catalog author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8179'), ('name', 'Canadiana NCF ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8189'), ('name', 'National Library of Israel J9U ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8234'), ('name', 'LiederNet author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8248'), ('name', 'Colon Classification')]
# [('p', 'http://www.wikidata.org/prop/direct/P8317'), ('name', 'Philadelphia Museum of Art entity ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8334'), ('name', 'MuseScore artist ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8385'), ('name', 'IDU person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P839'), ('name', 'IMSLP ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8406'), ('name', 'Grove Art Online ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8440'), ('name', 'Personendatenbank Germania Sacra ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8496'), ('name', 'Archive Site Trinity College Cambridge ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8566'), ('name', 'monumenta.ch ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8589'), ('name', 'Carl-Maria-von-Weber-Gesamtausgabe ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P866'), ('name', 'Perlentaucher ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8750'), ('name', 'Unione Romana Biblioteche Scientifiche ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8814'), ('name', 'WordNet 3.1 Synset ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8833'), ('name', 'Union Catalog of Armenian Libraries authority ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8848'), ('name', 'CONOR.AL ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8849'), ('name', 'CONOR.BG ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8850'), ('name', 'CONOR.KS ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8851'), ('name', 'CONOR.SR ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8902'), ('name', 'Archives at Yale names ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8947'), ('name', 'Museo Galileo authority ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8974'), ('name', 'SAPA ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8980'), ('name', 'KANTO ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8982'), ('name', 'Pontificio Istituto di Archeologia Cristiana ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P9000'), ('name', 'World History Encyclopedia ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P9017'), ('name', 'Medieval Manuscripts in Oxford Libraries person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P9037'), ('name', 'BHCL UUID')]
# [('p', 'http://www.wikidata.org/prop/direct/P906'), ('name', 'SELIBR ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P9081'), ('name', 'SEARCH on line catalogue ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P910'), ('name', "topic's main category")]
# [('p', 'http://www.wikidata.org/prop/direct/P9164'), ('name', 'Svenska Institutet i Rom ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P9179'), ('name', 'Biblioteca Iglesia Nacional Española en Roma ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P9223'), ('name', 'Provenio UUID')]
# [('p', 'http://www.wikidata.org/prop/direct/P9251'), ('name', 'Cyprus University of Technology ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P9282'), ('name', 'Catalogue of the Capitular Library of Verona author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P935'), ('name', 'Commons gallery')]
# [('p', 'http://www.wikidata.org/prop/direct/P947'), ('name', 'RSL ID (person)')]
# [('p', 'http://www.wikidata.org/prop/direct/P950'), ('name', 'Biblioteca Nacional de España ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P9507'), ('name', 'NBM authority ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P9563'), ('name', 'Encyclopedia of Renaissance Philosophy ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P9653'), ('name', 'Bod-Inc Online author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P9756'), ('name', 'Schoenberg Database of Manuscripts name ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7331'), ('name', 'Letteraturaitaliana.net author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8944'), ('name', 'Biblioteca Marciana owner ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P9041'), ('name', 'DiVo person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P9642'), ('name', 'Olschki author ID')]
# 225

# %%
# get all properties of 'Giovanni Boccaccio'
queryString = """
SELECT DISTINCT ?p ?pname ?o ?oname
WHERE {
   wd:Q1402 ?p ?o .
   # ?p sc:name ?pname.
   # ?o sc:name ?oname.
}
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P106'), ('pname', 'occupation'), ('o', 'http://www.wikidata.org/entity/Q15949613'), ('oname', 'short story writer')]
# [('p', 'http://www.wikidata.org/prop/direct/P20'), ('pname', 'place of death'), ('o', 'http://www.wikidata.org/entity/Q82646'), ('oname', 'Certaldo')]
# [('p', 'http://www.wikidata.org/prop/direct/P800'), ('pname', 'notable work'), ('o', 'http://www.wikidata.org/entity/Q16438'), ('oname', 'The Decameron')]
# [('p', 'http://www.wikidata.org/prop/direct/P27'), ('pname', 'country of citizenship'), ('o', 'http://www.wikidata.org/entity/Q148540'), ('oname', 'Republic of Florence')]
# [('p', 'http://www.wikidata.org/prop/direct/P1343'), ('pname', 'described by source'), ('o', 'http://www.wikidata.org/entity/Q19180675'), ('oname', 'Small Brockhaus and Efron Encyclopedic Dictionary')]
# [('p', 'http://www.wikidata.org/prop/direct/P106'), ('pname', 'occupation'), ('o', 'http://www.wikidata.org/entity/Q193391'), ('oname', 'diplomat')]
# [('p', 'http://www.wikidata.org/prop/direct/P19'), ('pname', 'place of birth'), ('o', 'http://www.wikidata.org/entity/Q2044'), ('oname', 'Florence')]
# [('p', 'http://www.wikidata.org/prop/direct/P6379'), ('pname', 'has works in the collection'), ('o', 'http://www.wikidata.org/entity/Q214867'), ('oname', 'National Gallery of Art')]
# [('p', 'http://www.wikidata.org/prop/direct/P1343'), ('pname', 'described by source'), ('o', 'http://www.wikidata.org/entity/Q302556'), ('oname', 'Catholic Encyclopedia')]
# [('p', 'http://www.wikidata.org/prop/direct/P1343'), ('pname', 'described by source'), ('o', 'http://www.wikidata.org/entity/Q3181656'), ('oname', 'The Nuttall Encyclopædia')]
# [('p', 'http://www.wikidata.org/prop/direct/P106'), ('pname', 'occupation'), ('o', 'http://www.wikidata.org/entity/Q333634'), ('oname', 'translator')]
# [('p', 'http://www.wikidata.org/prop/direct/P106'), ('pname', 'occupation'), ('o', 'http://www.wikidata.org/entity/Q36180'), ('oname', 'writer')]
# [('p', 'http://www.wikidata.org/prop/direct/P1412'), ('pname', 'languages spoken, written or signed'), ('o', 'http://www.wikidata.org/entity/Q397'), ('oname', 'Latin')]
# [('p', 'http://www.wikidata.org/prop/direct/P6886'), ('pname', 'writing language'), ('o', 'http://www.wikidata.org/entity/Q397'), ('oname', 'Latin')]
# [('p', 'http://www.wikidata.org/prop/direct/P106'), ('pname', 'occupation'), ('o', 'http://www.wikidata.org/entity/Q49757'), ('oname', 'poet')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pname', 'instance of'), ('o', 'http://www.wikidata.org/entity/Q5'), ('oname', 'human')]
# [('p', 'http://www.wikidata.org/prop/direct/P172'), ('pname', 'ethnic group'), ('o', 'http://www.wikidata.org/entity/Q50001'), ('oname', 'Italians')]
# [('p', 'http://www.wikidata.org/prop/direct/P1343'), ('pname', 'described by source'), ('o', 'http://www.wikidata.org/entity/Q51955019'), ('oname', 'BEIC Digital Library')]
# [('p', 'http://www.wikidata.org/prop/direct/P1343'), ('pname', 'described by source'), ('o', 'http://www.wikidata.org/entity/Q602358'), ('oname', 'Brockhaus and Efron Encyclopedic Dictionary')]
# [('p', 'http://www.wikidata.org/prop/direct/P1412'), ('pname', 'languages spoken, written or signed'), ('o', 'http://www.wikidata.org/entity/Q652'), ('oname', 'Italian')]
# [('p', 'http://www.wikidata.org/prop/direct/P103'), ('pname', 'native language'), ('o', 'http://www.wikidata.org/entity/Q652'), ('oname', 'Italian')]
# [('p', 'http://www.wikidata.org/prop/direct/P6886'), ('pname', 'writing language'), ('o', 'http://www.wikidata.org/entity/Q652'), ('oname', 'Italian')]
# [('p', 'http://www.wikidata.org/prop/direct/P21'), ('pname', 'sex or gender'), ('o', 'http://www.wikidata.org/entity/Q6581097'), ('oname', 'male')]
# [('p', 'http://www.wikidata.org/prop/direct/P1343'), ('pname', 'described by source'), ('o', 'http://www.wikidata.org/entity/Q67311526'), ('oname', 'Obalky knih.cz')]
# [('p', 'http://www.wikidata.org/prop/direct/P7763'), ('pname', 'copyright status as a creator'), ('o', 'http://www.wikidata.org/entity/Q71887839'), ('oname', 'copyrights on works have expired')]
# [('p', 'http://www.wikidata.org/prop/direct/P106'), ('pname', 'occupation'), ('o', 'http://www.wikidata.org/entity/Q864380'), ('oname', 'biographer')]
# [('p', 'http://www.wikidata.org/prop/direct/P1343'), ('pname', 'described by source'), ('o', 'http://www.wikidata.org/entity/Q867541'), ('oname', 'Encyclopædia Britannica 11th edition')]
# [('p', 'http://www.wikidata.org/prop/direct/P1066'), ('pname', 'student of'), ('o', 'http://www.wikidata.org/entity/Q736348'), ('oname', 'Cino da Pistoia')]
# [('p', 'http://www.wikidata.org/prop/direct/P735'), ('pname', 'given name'), ('o', 'http://www.wikidata.org/entity/Q1158906'), ('oname', 'Giovanni')]
# [('p', 'http://www.wikidata.org/prop/direct/P106'), ('pname', 'occupation'), ('o', 'http://www.wikidata.org/entity/Q24387326'), ('oname', 'mythographer')]
# [('p', 'http://www.wikidata.org/prop/direct/P509'), ('pname', 'cause of death'), ('o', 'http://www.wikidata.org/entity/Q152234'), ('oname', 'edema')]
# [('p', 'http://www.wikidata.org/prop/direct/P3342'), ('pname', 'significant person'), ('o', 'http://www.wikidata.org/entity/Q1401'), ('oname', 'Petrarch')]
# [('p', 'http://www.wikidata.org/prop/direct/P910'), ('pname', "topic's main category"), ('o', 'http://www.wikidata.org/entity/Q8492156'), ('oname', 'Category:Giovanni Boccaccio')]
# [('p', 'http://www.wikidata.org/prop/direct/P734'), ('pname', 'family name'), ('o', 'http://www.wikidata.org/entity/Q37556862'), ('oname', 'Boccaccio')]
# [('p', 'http://www.wikidata.org/prop/direct/P1424'), ('pname', "topic's main template"), ('o', 'http://www.wikidata.org/entity/Q20316889'), ('oname', 'Template:Giovanni Boccaccio')]
# [('p', 'http://www.wikidata.org/prop/direct/P119'), ('pname', 'place of burial'), ('o', 'http://www.wikidata.org/entity/Q3668236'), ('oname', 'Santi Jacopo e Filippo')]
# [('p', 'http://www.wikidata.org/prop/direct/P800'), ('pname', 'notable work'), ('o', 'http://www.wikidata.org/entity/Q3721314'), ('oname', 'Elegia di Madonna Fiammetta')]
# [('p', 'http://www.wikidata.org/prop/direct/P802'), ('pname', 'student'), ('o', 'http://www.wikidata.org/entity/Q773623'), ('oname', 'Benvenuto Rambaldi da Imola')]
# 38

# %%
# Get all 'written work' that have as author 'Giovanni Boccaccio'
queryString = """
SELECT DISTINCT ?ww ?name
WHERE {
   # ?ww wdt:P31 wd:Q47461344 .
   # ?ww wdt:P50 wd:Q1402 .
   # ?ww sc:name ?name.
}
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('ww', 'http://www.wikidata.org/entity/Q3759459'), ('name', 'Genealogia deorum gentilium')]
# [('ww', 'http://www.wikidata.org/entity/Q20630337'), ('name', 'De montibus')]
# [('ww', 'http://www.wikidata.org/entity/Q3792638'), ('name', 'Corbaccio')]
# [('ww', 'http://www.wikidata.org/entity/Q42192295'), ('name', 'The Life of Dante')]
# 4

# %%
# Get all 'literary work' that have as author 'Giovanni Boccaccio'
queryString = """
SELECT DISTINCT ?lw ?name
WHERE {
   # ?lw wdt:P31 wd:Q7725634 .
   # ?lw wdt:P50 wd:Q1402 .
   # ?lw sc:name ?name.
}
ORDER BY ASC(?lw)
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('lw', 'http://www.wikidata.org/entity/Q16438'), ('name', 'The Decameron')]
# [('lw', 'http://www.wikidata.org/entity/Q3614628'), ('name', 'Amorosa visione')]
# [('lw', 'http://www.wikidata.org/entity/Q3684237'), ('name', 'Comedia delle ninfe fiorentine')]
# [('lw', 'http://www.wikidata.org/entity/Q3721314'), ('name', 'Elegia di Madonna Fiammetta')]
# [('lw', 'http://www.wikidata.org/entity/Q3745486'), ('name', 'The Filocolo')]
# [('lw', 'http://www.wikidata.org/entity/Q3877086'), ('name', 'Ninfale fiesolano')]
# [('lw', 'http://www.wikidata.org/entity/Q5244311'), ('name', 'De casibus virorum illustrium')]
# [('lw', 'http://www.wikidata.org/entity/Q71736142'), ('name', 'De Canaria')]
# [('lw', 'http://www.wikidata.org/entity/Q86673964'), ('name', 'Mavortis Milex')]
# 9

# %%
# Get number of 'literary work' that have as author 'Giovanni Boccaccio'
queryString = """
SELECT ?author ?authorName (COUNT(DISTINCT ?lw) as ?literaryWorks)
WHERE {
   # ?lw wdt:P31 wd:Q7725634 .
   # ?lw wdt:P50 ?author .
   # ?author sc:name ?authorName.
   FILTER(?author = wd:Q1402)
}
GROUP BY ?author ?authorName
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('author', 'http://www.wikidata.org/entity/Q1402'), ('authorName', 'Giovanni Boccaccio'), ('literaryWorks', '10')]
# 1

# %%
# Get 'literary work' that have as author 'Giovanni Boccaccio'
queryString = """
SELECT ?author ?lw
WHERE {
   # ?lw wdt:P31 wd:Q7725634 .
   # ?lw wdt:P50 ?author .
   # ?author sc:name ?authorName.
   FILTER(?author = wd:Q1402)
}
ORDER BY ASC(?lw)
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('author', 'http://www.wikidata.org/entity/Q1402'), ('lw', 'http://www.wikidata.org/entity/Q16438')]
# [('author', 'http://www.wikidata.org/entity/Q1402'), ('lw', 'http://www.wikidata.org/entity/Q3614628')]
# [('author', 'http://www.wikidata.org/entity/Q1402'), ('lw', 'http://www.wikidata.org/entity/Q3649284')]
# [('author', 'http://www.wikidata.org/entity/Q1402'), ('lw', 'http://www.wikidata.org/entity/Q3684237')]
# [('author', 'http://www.wikidata.org/entity/Q1402'), ('lw', 'http://www.wikidata.org/entity/Q3721314')]
# [('author', 'http://www.wikidata.org/entity/Q1402'), ('lw', 'http://www.wikidata.org/entity/Q3745486')]
# [('author', 'http://www.wikidata.org/entity/Q1402'), ('lw', 'http://www.wikidata.org/entity/Q3877086')]
# [('author', 'http://www.wikidata.org/entity/Q1402'), ('lw', 'http://www.wikidata.org/entity/Q5244311')]
# [('author', 'http://www.wikidata.org/entity/Q1402'), ('lw', 'http://www.wikidata.org/entity/Q71736142')]
# [('author', 'http://www.wikidata.org/entity/Q1402'), ('lw', 'http://www.wikidata.org/entity/Q86673964')]
# 10

# %% [markdown]
# Final query for this task

# %%
# Comparing literary works of 'Giovanni Boccaccio' with 'Dante Alighieri'
queryString = """
SELECT ?author ?authorName (COUNT(DISTINCT ?lw) as ?literaryWorks)
WHERE {
   # ?lw wdt:P31 wd:Q7725634 .
   # ?lw wdt:P50 ?author .
   # ?author sc:name ?authorName.
   FILTER(?author = wd:Q1402 || ?author = wd:Q1067)
}
GROUP BY ?author ?authorName
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('author', 'http://www.wikidata.org/entity/Q1402'), ('authorName', 'Giovanni Boccaccio'), ('literaryWorks', '10')]
# [('author', 'http://www.wikidata.org/entity/Q1067'), ('authorName', 'Dante Alighieri'), ('literaryWorks', '37')]
# 2

# %% [markdown]
# ## Task 7
# Consider italian poets, their place of birth (the city) and their university education. Return for each city the number of poets who born there and who was educated there (the result set must be a list of triples city IRI, label and #poets).

# %%
# Get all subjects that have 'poet' as 'occupation'
queryString = """
SELECT DISTINCT ?poet ?name
WHERE {
   # ?poet wdt:P106 wd:Q49757 .
   # ?poet sc:name ?name.
}
LIMIT 10
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('poet', 'http://www.wikidata.org/entity/Q1373516'), ('name', 'Eugénio de Castro')]
# [('poet', 'http://www.wikidata.org/entity/Q589406'), ('name', 'Empress Xiaoquancheng')]
# [('poet', 'http://www.wikidata.org/entity/Q610608'), ('name', 'António Aleixo')]
# [('poet', 'http://www.wikidata.org/entity/Q710504'), ('name', 'Bohuslav Balbín')]
# [('poet', 'http://www.wikidata.org/entity/Q8188119'), ('name', 'Adelina Lopes Vieira')]
# [('poet', 'http://www.wikidata.org/entity/Q8201526'), ('name', 'Antonio Márquez Salas')]
# [('poet', 'http://www.wikidata.org/entity/Q8201629'), ('name', 'Antonio Rendic')]
# [('poet', 'http://www.wikidata.org/entity/Q8202094'), ('name', 'Antônio de Castro Assumpção')]
# [('poet', 'http://www.wikidata.org/entity/Q8246828'), ('name', 'Bernat Català de Valleriola')]
# [('poet', 'http://www.wikidata.org/entity/Q1191225'), ('name', 'Tan Sitong')]
# 10

# %%
# Get 'ethnic group' of 'Dante Alighieri'
queryString = """
SELECT DISTINCT ?e ?name
WHERE {
   wd:Q1067 wdt:P172 ?e .
   # ?e sc:name ?name.
}
LIMIT 10
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('e', 'http://www.wikidata.org/entity/Q50001'), ('name', 'Italians')]
# 1

# %% [markdown]
# I assume italian poets are all poets with `ethnic group` wd:Q50001 (Italians)

# %%
# Get all subjects that have 'poet' as 'occupation' and 'Italians' as 'ethnic group'
queryString = """
SELECT DISTINCT ?poet ?name
WHERE {
   # ?poet wdt:P106 wd:Q49757 .
   # ?poet wdt:P172 wd:Q50001 .
   # ?poet sc:name ?name.
}
LIMIT 10
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('poet', 'http://www.wikidata.org/entity/Q296272'), ('name', 'Pietro Aretino')]
# [('poet', 'http://www.wikidata.org/entity/Q982512'), ('name', 'Giuseppe Giusti')]
# [('poet', 'http://www.wikidata.org/entity/Q55433'), ('name', 'Michelangelo Antonioni')]
# [('poet', 'http://www.wikidata.org/entity/Q83321'), ('name', 'Giacomo Casanova')]
# [('poet', 'http://www.wikidata.org/entity/Q182046'), ('name', 'Leon Battista Alberti')]
# [('poet', 'http://www.wikidata.org/entity/Q48900'), ('name', 'Ludovico Ariosto')]
# [('poet', 'http://www.wikidata.org/entity/Q165534'), ('name', 'Carlo Goldoni')]
# [('poet', 'http://www.wikidata.org/entity/Q7803'), ('name', 'Bronzino')]
# [('poet', 'http://www.wikidata.org/entity/Q982387'), ('name', 'Giovanni Capurro')]
# [('poet', 'http://www.wikidata.org/entity/Q1067'), ('name', 'Dante Alighieri')]
# 10

# %%
# Get 'place of birth' of 'Dante Alighieri'
queryString = """
SELECT DISTINCT ?pob ?pobName
WHERE {
   wd:Q1067 wdt:P19 ?pob .
   # ?pob sc:name ?pobName.
}
LIMIT 10
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('pob', 'http://www.wikidata.org/entity/Q2044'), ('pobName', 'Florence')]
# 1

# %%
# Get all the cities in which italian poets were born
queryString = """
SELECT DISTINCT ?pob ?pobName
WHERE {
   # ?poet wdt:P106 wd:Q49757 .
   # ?poet wdt:P172 wd:Q50001 .
   # ?poet wdt:P19 ?pob .
   # ?pob sc:name ?pobName.
}
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('pob', 'http://www.wikidata.org/entity/Q13378'), ('pobName', 'Arezzo')]
# [('pob', 'http://www.wikidata.org/entity/Q1449'), ('pobName', 'Genoa')]
# [('pob', 'http://www.wikidata.org/entity/Q1722'), ('pobName', 'Dubrovnik')]
# [('pob', 'http://www.wikidata.org/entity/Q219330'), ('pobName', 'Pietrasanta')]
# [('pob', 'http://www.wikidata.org/entity/Q52069'), ('pobName', 'Caprese Michelangelo')]
# [('pob', 'http://www.wikidata.org/entity/Q1335'), ('pobName', 'Montevideo')]
# [('pob', 'http://www.wikidata.org/entity/Q13362'), ('pobName', 'Ferrara')]
# [('pob', 'http://www.wikidata.org/entity/Q144880'), ('pobName', 'Zakynthos')]
# [('pob', 'http://www.wikidata.org/entity/Q2044'), ('pobName', 'Florence')]
# [('pob', 'http://www.wikidata.org/entity/Q220'), ('pobName', 'Rome')]
# [('pob', 'http://www.wikidata.org/entity/Q2634'), ('pobName', 'Naples')]
# [('pob', 'http://www.wikidata.org/entity/Q2683'), ('pobName', 'Parma')]
# [('pob', 'http://www.wikidata.org/entity/Q490'), ('pobName', 'Milan')]
# [('pob', 'http://www.wikidata.org/entity/Q6247'), ('pobName', 'Mantua')]
# [('pob', 'http://www.wikidata.org/entity/Q641'), ('pobName', 'Venice')]
# [('pob', 'http://www.wikidata.org/entity/Q84'), ('pobName', 'London')]
# [('pob', 'http://www.wikidata.org/entity/Q13360'), ('pobName', 'Reggio Emilia')]
# [('pob', 'http://www.wikidata.org/entity/Q13678'), ('pobName', 'Agrigento')]
# [('pob', 'http://www.wikidata.org/entity/Q20103'), ('pobName', 'Assisi')]
# [('pob', 'http://www.wikidata.org/entity/Q20454'), ('pobName', 'Saluzzo')]
# [('pob', 'http://www.wikidata.org/entity/Q39790'), ('pobName', 'Sangiano')]
# [('pob', 'http://www.wikidata.org/entity/Q6122'), ('pobName', 'Asti')]
# [('pob', 'http://www.wikidata.org/entity/Q6231'), ('pobName', 'Cremona')]
# [('pob', 'http://www.wikidata.org/entity/Q6244'), ('pobName', 'Lodi')]
# [('pob', 'http://www.wikidata.org/entity/Q83362'), ('pobName', 'Recanati')]
# [('pob', 'http://www.wikidata.org/entity/Q270613'), ('pobName', 'Celle Ligure')]
# [('pob', 'http://www.wikidata.org/entity/Q617'), ('pobName', 'Padua')]
# [('pob', 'http://www.wikidata.org/entity/Q87'), ('pobName', 'Alexandria')]
# [('pob', 'http://www.wikidata.org/entity/Q102634'), ('pobName', 'Monsummano Terme')]
# [('pob', 'http://www.wikidata.org/entity/Q117032'), ('pobName', 'Pico, Lazio')]
# [('pob', 'http://www.wikidata.org/entity/Q56687351'), ('pobName', 'Valdicastello Carducci')]
# 31

# %%
# Get all subjects that have 'poet' as 'occupation' and 'Italians' as 'ethnic group' and their date of birth
queryString = """
SELECT DISTINCT ?poet ?name ?dob
WHERE {
   # ?poet wdt:P106 wd:Q49757 .
   # ?poet wdt:P172 wd:Q50001 .
   # ?poet wdt:P569 ?dob .
   # ?poet sc:name ?name.
}
ORDER BY DESC(?dob)
LIMIT 10
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('poet', 'http://www.wikidata.org/entity/Q53009'), ('name', 'Bernardo Bertolucci'), ('dob', '1941-03-16T00:00:00Z')]
# [('poet', 'http://www.wikidata.org/entity/Q765'), ('name', 'Dario Fo'), ('dob', '1926-03-24T00:00:00Z')]
# [('poet', 'http://www.wikidata.org/entity/Q55433'), ('name', 'Michelangelo Antonioni'), ('dob', '1912-09-29T00:00:00Z')]
# [('poet', 'http://www.wikidata.org/entity/Q560541'), ('name', 'Tommaso Landolfi'), ('dob', '1908-08-09T00:00:00Z')]
# [('poet', 'http://www.wikidata.org/entity/Q334147'), ('name', 'Julius Evola'), ('dob', '1898-05-19T00:00:00Z')]
# [('poet', 'http://www.wikidata.org/entity/Q7368989'), ('name', 'Rosita Melo'), ('dob', '1897-07-09T00:00:00Z')]
# [('poet', 'http://www.wikidata.org/entity/Q311802'), ('name', 'Giuseppe Ungaretti'), ('dob', '1888-02-10T00:00:00Z')]
# [('poet', 'http://www.wikidata.org/entity/Q311802'), ('name', 'Giuseppe Ungaretti'), ('dob', '1888-02-08T00:00:00Z')]
# [('poet', 'http://www.wikidata.org/entity/Q133855'), ('name', 'Guillaume Apollinaire'), ('dob', '1880-08-26T00:00:00Z')]
# [('poet', 'http://www.wikidata.org/entity/Q216582'), ('name', 'Filippo Tommaso Marinettiz6eztfzitryxi'), ('dob', '1876-12-22T00:00:00Z')]
# 10

# %%
# Get all properties of 'Bernardo Bertolucci'
queryString = """
SELECT DISTINCT ?p ?name
WHERE {
   wd:Q53009 ?p ?o.
   # ?p sc:name ?name.
}
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P1005'), ('name', 'Portuguese National Library ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1006'), ('name', 'Nationale Thesaurus voor Auteurs ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1015'), ('name', 'NORAF ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1050'), ('name', 'medical condition')]
# [('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('p', 'http://www.wikidata.org/prop/direct/P1196'), ('name', 'manner of death')]
# [('p', 'http://www.wikidata.org/prop/direct/P1207'), ('name', 'NUKAT ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1258'), ('name', 'Rotten Tomatoes ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1263'), ('name', 'NNDB people ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1266'), ('name', 'AlloCiné person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1273'), ('name', 'CANTIC ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1280'), ('name', 'CONOR.SI ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1283'), ('name', 'filmography')]
# [('p', 'http://www.wikidata.org/prop/direct/P1284'), ('name', 'Munzinger person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1296'), ('name', 'Gran Enciclopèdia Catalana ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1315'), ('name', 'NLA Trove ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1343'), ('name', 'described by source')]
# [('p', 'http://www.wikidata.org/prop/direct/P1368'), ('name', 'LNB ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1375'), ('name', 'NSK ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P140'), ('name', 'religion')]
# [('p', 'http://www.wikidata.org/prop/direct/P1411'), ('name', 'nominated for')]
# [('p', 'http://www.wikidata.org/prop/direct/P1412'), ('name', 'languages spoken, written or signed')]
# [('p', 'http://www.wikidata.org/prop/direct/P1417'), ('name', 'Encyclopædia Britannica Online ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1580'), ('name', 'University of Barcelona authority ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1649'), ('name', 'KMDb person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P166'), ('name', 'award received')]
# [('p', 'http://www.wikidata.org/prop/direct/P1712'), ('name', 'Metacritic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P172'), ('name', 'ethnic group')]
# [('p', 'http://www.wikidata.org/prop/direct/P1741'), ('name', 'GTAA ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P18'), ('name', 'image')]
# [('p', 'http://www.wikidata.org/prop/direct/P19'), ('name', 'place of birth')]
# [('p', 'http://www.wikidata.org/prop/direct/P1953'), ('name', 'Discogs artist ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1969'), ('name', 'MovieMeter director ID (former scheme)')]
# [('p', 'http://www.wikidata.org/prop/direct/P1986'), ('name', 'Biographical Dictionary of Italian People ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P20'), ('name', 'place of death')]
# [('p', 'http://www.wikidata.org/prop/direct/P2019'), ('name', 'AllMovie person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2031'), ('name', 'work period (start)')]
# [('p', 'http://www.wikidata.org/prop/direct/P21'), ('name', 'sex or gender')]
# [('p', 'http://www.wikidata.org/prop/direct/P213'), ('name', 'ISNI')]
# [('p', 'http://www.wikidata.org/prop/direct/P214'), ('name', 'VIAF ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2163'), ('name', 'FAST ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2168'), ('name', 'Swedish Film Database person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2174'), ('name', 'Museum of Modern Art artist ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P22'), ('name', 'father')]
# [('p', 'http://www.wikidata.org/prop/direct/P227'), ('name', 'GND ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2387'), ('name', 'Elonet person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2435'), ('name', 'PORT person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P244'), ('name', 'Library of Congress authority ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P245'), ('name', 'Union List of Artist Names ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2519'), ('name', 'Scope.dk person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P26'), ('name', 'spouse')]
# [('p', 'http://www.wikidata.org/prop/direct/P2600'), ('name', 'Geni.com profile ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2604'), ('name', 'Kinopoisk person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2605'), ('name', 'ČSFD person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2626'), ('name', 'Danish National Filmography person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2638'), ('name', 'TV.com ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2639'), ('name', 'Filmportal ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P268'), ('name', 'Bibliothèque nationale de France ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P269'), ('name', 'IdRef ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P27'), ('name', 'country of citizenship')]
# [('p', 'http://www.wikidata.org/prop/direct/P271'), ('name', 'CiNii author ID (books)')]
# [('p', 'http://www.wikidata.org/prop/direct/P2924'), ('name', 'Great Russian Encyclopedia Online ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2949'), ('name', 'WikiTree person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3056'), ('name', 'TCM Movie Database person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('name', 'instance of')]
# [('p', 'http://www.wikidata.org/prop/direct/P3136'), ('name', 'elCinema person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3204'), ('name', 'Ciné-Ressources person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3219'), ('name', 'Encyclopædia Universalis ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3305'), ('name', 'KINENOTE person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3365'), ('name', 'Treccani ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3373'), ('name', 'sibling')]
# [('p', 'http://www.wikidata.org/prop/direct/P3430'), ('name', 'SNAC ARK ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P345'), ('name', 'IMDb ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P349'), ('name', 'National Diet Library ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3569'), ('name', 'Cultureel Woordenboek ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3630'), ('name', 'Babelio author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P373'), ('name', 'Commons category')]
# [('p', 'http://www.wikidata.org/prop/direct/P3762'), ('name', 'openMLOL author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3782'), ('name', 'Artnet artist ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3846'), ('name', 'DBC author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P39'), ('name', 'position held')]
# [('p', 'http://www.wikidata.org/prop/direct/P396'), ('name', 'SBN author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3987'), ('name', 'SHARE Catalogue author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P409'), ('name', 'Libraries Australia ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P4223'), ('name', "Treccani's Enciclopedia Italiana ID")]
# [('p', 'http://www.wikidata.org/prop/direct/P4293'), ('name', 'PM20 folder ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P434'), ('name', 'MusicBrainz artist ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P4342'), ('name', 'Store norske leksikon ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P4399'), ('name', 'Itaú Cultural ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P4438'), ('name', 'BFI Films, TV and people ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P4768'), ('name', 'cinematografo.it name or company ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P4782'), ('name', 'Movieplayer person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P4985'), ('name', 'TMDb person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5034'), ('name', 'National Library of Korea ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5063'), ('name', 'Interlingual Index ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P509'), ('name', 'cause of death')]
# [('p', 'http://www.wikidata.org/prop/direct/P5254'), ('name', 'FilmTv.it person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5284'), ('name', 'Douban movie celebrity ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5340'), ('name', 'American Film Institute person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P551'), ('name', 'residence')]
# [('p', 'http://www.wikidata.org/prop/direct/P5534'), ('name', 'Open Media Database person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5587'), ('name', 'Libris-URI')]
# [('p', 'http://www.wikidata.org/prop/direct/P5617'), ('name', 'Evene ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P569'), ('name', 'date of birth')]
# [('p', 'http://www.wikidata.org/prop/direct/P570'), ('name', 'date of death')]
# [('p', 'http://www.wikidata.org/prop/direct/P6150'), ('name', 'Academy Awards Database nominee ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6379'), ('name', 'has works in the collection')]
# [('p', 'http://www.wikidata.org/prop/direct/P646'), ('name', 'Freebase ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P648'), ('name', 'Open Library ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6844'), ('name', 'abART person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P69'), ('name', 'educated at')]
# [('p', 'http://www.wikidata.org/prop/direct/P691'), ('name', 'NKCR AUT ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7084'), ('name', 'related category')]
# [('p', 'http://www.wikidata.org/prop/direct/P7214'), ('name', 'Allcinema person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7293'), ('name', 'PLWABN ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P734'), ('name', 'family name')]
# [('p', 'http://www.wikidata.org/prop/direct/P735'), ('name', 'given name')]
# [('p', 'http://www.wikidata.org/prop/direct/P7666'), ('name', 'Visuotinė lietuvių enciklopedija ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7763'), ('name', 'copyright status as a creator')]
# [('p', 'http://www.wikidata.org/prop/direct/P7803'), ('name', 'Decine21 person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7859'), ('name', 'WorldCat Identities ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7865'), ('name', 'CoBiS author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7902'), ('name', 'Deutsche Biographie (GND) ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7982'), ('name', 'Hrvatska enciklopedija ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8349'), ('name', 'Proleksis enciklopedija ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8793'), ('name', 'Quirinale ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8814'), ('name', 'WordNet 3.1 Synset ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8849'), ('name', 'CONOR.BG ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8971'), ('name', 'Cinémathèque québécoise person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P906'), ('name', 'SELIBR ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P910'), ('name', "topic's main category")]
# [('p', 'http://www.wikidata.org/prop/direct/P949'), ('name', 'National Library of Israel ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P950'), ('name', 'Biblioteca Nacional de España ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P973'), ('name', 'described at URL')]
# [('p', 'http://www.wikidata.org/prop/direct/P9807'), ('name', 'SNK ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P990'), ('name', "audio recording of the subject's spoken voice")]
# [('p', 'http://www.wikidata.org/prop/direct/P3144'), ('name', 'elFilm person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P4781'), ('name', 'MYmovies director ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P9880'), ('name', 'Festivaletteratura person ID')]
# 139

# %%
# Get info about 'Bernardo Bertolucci' education
queryString = """
SELECT DISTINCT ?o ?name
WHERE {
   wd:Q53009 wdt:P69 ?o.
   # ?o sc:name ?name.
}
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('o', 'http://www.wikidata.org/entity/Q209344'), ('name', 'Sapienza University of Rome')]
# 1

# %%
# Get info about 'Sapienza University of Rome'
queryString = """
SELECT DISTINCT ?p ?name
WHERE {
   wd:Q209344 ?p ?o.
   # ?p sc:name ?name.
}
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P9871'), ('name', 'INAPP author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1015'), ('name', 'NORAF ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1017'), ('name', 'Vatican Library ID (former scheme)')]
# [('p', 'http://www.wikidata.org/prop/direct/P112'), ('name', 'founded by')]
# [('p', 'http://www.wikidata.org/prop/direct/P1128'), ('name', 'employees')]
# [('p', 'http://www.wikidata.org/prop/direct/P1207'), ('name', 'NUKAT ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1273'), ('name', 'CANTIC ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P131'), ('name', 'located in the administrative territorial entity')]
# [('p', 'http://www.wikidata.org/prop/direct/P138'), ('name', 'named after')]
# [('p', 'http://www.wikidata.org/prop/direct/P1416'), ('name', 'affiliation')]
# [('p', 'http://www.wikidata.org/prop/direct/P1417'), ('name', 'Encyclopædia Britannica Online ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P159'), ('name', 'headquarters location')]
# [('p', 'http://www.wikidata.org/prop/direct/P1607'), ('name', 'Dialnet author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1612'), ('name', 'Commons Institution page')]
# [('p', 'http://www.wikidata.org/prop/direct/P1670'), ('name', 'Canadiana Authorities ID (former scheme)')]
# [('p', 'http://www.wikidata.org/prop/direct/P17'), ('name', 'country')]
# [('p', 'http://www.wikidata.org/prop/direct/P18'), ('name', 'image')]
# [('p', 'http://www.wikidata.org/prop/direct/P2002'), ('name', 'Twitter username')]
# [('p', 'http://www.wikidata.org/prop/direct/P2003'), ('name', 'Instagram username')]
# [('p', 'http://www.wikidata.org/prop/direct/P2013'), ('name', 'Facebook ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P213'), ('name', 'ISNI')]
# [('p', 'http://www.wikidata.org/prop/direct/P214'), ('name', 'VIAF ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2196'), ('name', 'students count')]
# [('p', 'http://www.wikidata.org/prop/direct/P227'), ('name', 'GND ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2427'), ('name', 'GRID ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P244'), ('name', 'Library of Congress authority ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P245'), ('name', 'Union List of Artist Names ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P268'), ('name', 'Bibliothèque nationale de France ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P269'), ('name', 'IdRef ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P271'), ('name', 'CiNii author ID (books)')]
# [('p', 'http://www.wikidata.org/prop/direct/P276'), ('name', 'location')]
# [('p', 'http://www.wikidata.org/prop/direct/P2924'), ('name', 'Great Russian Encyclopedia Online ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2936'), ('name', 'language used')]
# [('p', 'http://www.wikidata.org/prop/direct/P3065'), ('name', 'RERO ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('name', 'instance of')]
# [('p', 'http://www.wikidata.org/prop/direct/P3153'), ('name', 'Crossref funder ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3280'), ('name', 'BAnQ author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3417'), ('name', 'Quora topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P349'), ('name', 'National Diet Library ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3500'), ('name', 'Ringgold ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P355'), ('name', 'subsidiary')]
# [('p', 'http://www.wikidata.org/prop/direct/P3608'), ('name', 'EU VAT number')]
# [('p', 'http://www.wikidata.org/prop/direct/P373'), ('name', 'Commons category')]
# [('p', 'http://www.wikidata.org/prop/direct/P3762'), ('name', 'openMLOL author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3876'), ('name', 'category for alumni of educational institution')]
# [('p', 'http://www.wikidata.org/prop/direct/P3987'), ('name', 'SHARE Catalogue author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P409'), ('name', 'Libraries Australia ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P4195'), ('name', 'category for employees of the organization')]
# [('p', 'http://www.wikidata.org/prop/direct/P4339'), ('name', 'Radio Radicale organizer ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P463'), ('name', 'member of')]
# [('p', 'http://www.wikidata.org/prop/direct/P5242'), ('name', 'ARWU university ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5492'), ('name', 'EDIT16 catalogue author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5584'), ('name', 'QS World University ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5586'), ('name', 'Times Higher Education World University ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5600'), ('name', 'U-Multirank university ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P571'), ('name', 'inception')]
# [('p', 'http://www.wikidata.org/prop/direct/P5739'), ('name', 'Pontificia Università della Santa Croce ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5785'), ('name', 'EU Research participant ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6364'), ('name', 'official color(s)')]
# [('p', 'http://www.wikidata.org/prop/direct/P6366'), ('name', 'Microsoft Academic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P646'), ('name', 'Freebase ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6773'), ('name', 'HAL structure ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6782'), ('name', 'ROR ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P691'), ('name', 'NKCR AUT ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7699'), ('name', 'National Library of Lithuania ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7859'), ('name', 'WorldCat Identities ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8034'), ('name', 'Vatican Library VcBA ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8179'), ('name', 'Canadiana NCF ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8189'), ('name', 'National Library of Israel J9U ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P856'), ('name', 'official website')]
# [('p', 'http://www.wikidata.org/prop/direct/P8687'), ('name', 'social media followers')]
# [('p', 'http://www.wikidata.org/prop/direct/P910'), ('name', "topic's main category")]
# [('p', 'http://www.wikidata.org/prop/direct/P9226'), ('name', 'ARAE ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P935'), ('name', 'Commons gallery')]
# [('p', 'http://www.wikidata.org/prop/direct/P950'), ('name', 'Biblioteca Nacional de España ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2740'), ('name', 'ResearchGate institute ID')]
# 76

# %%
# Get info about 'Sapienza University of Rome'
queryString = """
SELECT DISTINCT ?instanceOf ?name
WHERE {
   wd:Q209344 wdt:P31 ?instanceOf.
   # ?instanceOf sc:name ?name.
}
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('instanceOf', 'http://www.wikidata.org/entity/Q875538'), ('name', 'public university')]
# 1

# %%
# Get info about 'public university'
queryString = """
SELECT DISTINCT ?p ?name
WHERE {
   wd:Q875538 ?p ?o.
   # ?p sc:name ?name.
}
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P101'), ('name', 'field of work')]
# [('p', 'http://www.wikidata.org/prop/direct/P1149'), ('name', 'Library of Congress Classification')]
# [('p', 'http://www.wikidata.org/prop/direct/P18'), ('name', 'image')]
# [('p', 'http://www.wikidata.org/prop/direct/P1889'), ('name', 'different from')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('name', 'properties for this type')]
# [('p', 'http://www.wikidata.org/prop/direct/P2163'), ('name', 'FAST ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P244'), ('name', 'Library of Congress authority ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2581'), ('name', 'BabelNet ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('name', 'subclass of')]
# [('p', 'http://www.wikidata.org/prop/direct/P3417'), ('name', 'Quora topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P349'), ('name', 'National Diet Library ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P373'), ('name', 'Commons category')]
# [('p', 'http://www.wikidata.org/prop/direct/P3847'), ('name', 'Open Library subject ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P461'), ('name', 'opposite of')]
# [('p', 'http://www.wikidata.org/prop/direct/P646'), ('name', 'Freebase ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8408'), ('name', 'KBpedia ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P910'), ('name', "topic's main category")]
# 17

# %%
# Get info about super class of 'public university'
queryString = """
SELECT DISTINCT ?super ?name
WHERE {
   wd:Q875538 wdt:P279 ?super.
   # ?super sc:name ?name.
}
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('super', 'http://www.wikidata.org/entity/Q23002037'), ('name', 'public educational institution')]
# [('super', 'http://www.wikidata.org/entity/Q3918'), ('name', 'university')]
# 2

# %%
# Get info country of 'Sapienza University of Rome'
queryString = """
SELECT DISTINCT ?o ?name
WHERE {
   wd:Q209344 wdt:P17 ?o.
   # ?o sc:name ?name.
}
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('o', 'http://www.wikidata.org/entity/Q38'), ('name', 'Italy')]
# 1

# %%
# Get info location of 'Sapienza University of Rome'
queryString = """
SELECT DISTINCT ?o ?name
WHERE {
   wd:Q209344 wdt:P131 ?o.
   # ?o sc:name ?name.
}
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('o', 'http://www.wikidata.org/entity/Q220'), ('name', 'Rome')]
# 1

# %%
# Get all subjects that have 'poet' as 'occupation' and 'Italians' as 'ethnic group' and their date of birth
# Get informations about theirs studies
queryString = """
SELECT ?educatedAt ?name
WHERE {
   # ?poet wdt:P106 wd:Q49757 .     #BGP for poet
   # ?poet wdt:P172 wd:Q50001 .     #BGP for 'Italians'
   
   # ?poet wdt:P69 ?educatedAt .    #BGP for educated at
   
   # ?educatedAt sc:name ?name.
}
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('educatedAt', 'http://www.wikidata.org/entity/Q209344'), ('name', 'Sapienza University of Rome')]
# [('educatedAt', 'http://www.wikidata.org/entity/Q209344'), ('name', 'Sapienza University of Rome')]
# [('educatedAt', 'http://www.wikidata.org/entity/Q1243705'), ('name', 'University of Modena and Reggio Emilia')]
# [('educatedAt', 'http://www.wikidata.org/entity/Q219317'), ('name', 'University of Pavia')]
# [('educatedAt', 'http://www.wikidata.org/entity/Q680971'), ('name', 'Experimental Centre of Cinematography')]
# [('educatedAt', 'http://www.wikidata.org/entity/Q131262'), ('name', 'University of Bologna')]
# [('educatedAt', 'http://www.wikidata.org/entity/Q131262'), ('name', 'University of Bologna')]
# [('educatedAt', 'http://www.wikidata.org/entity/Q131262'), ('name', 'University of Bologna')]
# [('educatedAt', 'http://www.wikidata.org/entity/Q152171'), ('name', 'University of Bonn')]
# [('educatedAt', 'http://www.wikidata.org/entity/Q193510'), ('name', 'University of Padua')]
# [('educatedAt', 'http://www.wikidata.org/entity/Q193510'), ('name', 'University of Padua')]
# [('educatedAt', 'http://www.wikidata.org/entity/Q193510'), ('name', 'University of Padua')]
# [('educatedAt', 'http://www.wikidata.org/entity/Q193510'), ('name', 'University of Padua')]
# [('educatedAt', 'http://www.wikidata.org/entity/Q209842'), ('name', 'University of Paris')]
# [('educatedAt', 'http://www.wikidata.org/entity/Q820887'), ('name', 'University of Florence')]
# [('educatedAt', 'http://www.wikidata.org/entity/Q820887'), ('name', 'University of Florence')]
# [('educatedAt', 'http://www.wikidata.org/entity/Q955609'), ('name', 'University of Ferrara')]
# [('educatedAt', 'http://www.wikidata.org/entity/Q593321'), ('name', 'University of Genoa')]
# [('educatedAt', 'http://www.wikidata.org/entity/Q593321'), ('name', 'University of Genoa')]
# [('educatedAt', 'http://www.wikidata.org/entity/Q270920'), ('name', 'Royal Academy of Arts')]
# [('educatedAt', 'http://www.wikidata.org/entity/Q645663'), ('name', 'University of Pisa')]
# [('educatedAt', 'http://www.wikidata.org/entity/Q672416'), ('name', 'Scuola Normale Superiore')]
# [('educatedAt', 'http://www.wikidata.org/entity/Q776223'), ('name', 'University of Montpellier')]
# [('educatedAt', 'http://www.wikidata.org/entity/Q338472'), ('name', 'Brera Academy')]
# [('educatedAt', 'http://www.wikidata.org/entity/Q6410900'), ('name', "King's College School")]
# [('educatedAt', 'http://www.wikidata.org/entity/Q52846967'), ('name', 'ITI L.Da Vinci')]
# [('educatedAt', 'http://www.wikidata.org/entity/Q5142868'), ('name', 'Colegio Niño Jesús de Praga')]
# 27

# %%
# Get all subjects that have 'poet' as 'occupation' and 'Italians' as 'ethnic group' and their date of birth
# Get the universities 
queryString = """
SELECT ?uni ?name
WHERE {
   # ?poet wdt:P106 wd:Q49757 .     #BGP for poet
   # ?poet wdt:P172 wd:Q50001 .     #BGP for 'Italians'
   
   # ?poet wdt:P69 ?educatedAt .    #BGP for educated at
   # ?educatedAt wdt:P31 ?uni.
   
   # ?uni sc:name ?name

}
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('uni', 'http://www.wikidata.org/entity/Q3953379'), ('name', 'superior graduate school in Italy')]
# [('uni', 'http://www.wikidata.org/entity/Q2418495'), ('name', 'independent school')]
# [('uni', 'http://www.wikidata.org/entity/Q1966910'), ('name', 'national academy')]
# [('uni', 'http://www.wikidata.org/entity/Q1352795'), ('name', 'cinematheque')]
# [('uni', 'http://www.wikidata.org/entity/Q380093'), ('name', 'film school')]
# [('uni', 'http://www.wikidata.org/entity/Q207694'), ('name', 'art museum')]
# [('uni', 'http://www.wikidata.org/entity/Q2668072'), ('name', 'collection')]
# [('uni', 'http://www.wikidata.org/entity/Q3918'), ('name', 'university')]
# [('uni', 'http://www.wikidata.org/entity/Q3918'), ('name', 'university')]
# [('uni', 'http://www.wikidata.org/entity/Q3918'), ('name', 'university')]
# [('uni', 'http://www.wikidata.org/entity/Q3918'), ('name', 'university')]
# [('uni', 'http://www.wikidata.org/entity/Q3918'), ('name', 'university')]
# [('uni', 'http://www.wikidata.org/entity/Q3918'), ('name', 'university')]
# [('uni', 'http://www.wikidata.org/entity/Q3918'), ('name', 'university')]
# [('uni', 'http://www.wikidata.org/entity/Q3918'), ('name', 'university')]
# [('uni', 'http://www.wikidata.org/entity/Q3918'), ('name', 'university')]
# [('uni', 'http://www.wikidata.org/entity/Q3918'), ('name', 'university')]
# [('uni', 'http://www.wikidata.org/entity/Q3918'), ('name', 'university')]
# [('uni', 'http://www.wikidata.org/entity/Q3918'), ('name', 'university')]
# [('uni', 'http://www.wikidata.org/entity/Q45400320'), ('name', 'open-access publisher')]
# [('uni', 'http://www.wikidata.org/entity/Q45400320'), ('name', 'open-access publisher')]
# [('uni', 'http://www.wikidata.org/entity/Q45400320'), ('name', 'open-access publisher')]
# [('uni', 'http://www.wikidata.org/entity/Q45400320'), ('name', 'open-access publisher')]
# [('uni', 'http://www.wikidata.org/entity/Q45400320'), ('name', 'open-access publisher')]
# [('uni', 'http://www.wikidata.org/entity/Q45400320'), ('name', 'open-access publisher')]
# [('uni', 'http://www.wikidata.org/entity/Q3551775'), ('name', 'university in France')]
# [('uni', 'http://www.wikidata.org/entity/Q3551775'), ('name', 'university in France')]
# [('uni', 'http://www.wikidata.org/entity/Q62078547'), ('name', 'public research university')]
# [('uni', 'http://www.wikidata.org/entity/Q1767829'), ('name', 'comprehensive university')]
# [('uni', 'http://www.wikidata.org/entity/Q875538'), ('name', 'public university')]
# [('uni', 'http://www.wikidata.org/entity/Q875538'), ('name', 'public university')]
# [('uni', 'http://www.wikidata.org/entity/Q875538'), ('name', 'public university')]
# [('uni', 'http://www.wikidata.org/entity/Q875538'), ('name', 'public university')]
# [('uni', 'http://www.wikidata.org/entity/Q875538'), ('name', 'public university')]
# [('uni', 'http://www.wikidata.org/entity/Q618123'), ('name', 'geographical feature')]
# [('uni', 'http://www.wikidata.org/entity/Q641347'), ('name', 'Local Internet registry')]
# [('uni', 'http://www.wikidata.org/entity/Q383092'), ('name', 'art school')]
# [('uni', 'http://www.wikidata.org/entity/Q3803834'), ('name', 'istituto tecnico')]
# 38

# %%
# Get all subjects that have 'poet' as 'occupation' and 'Italians' as 'ethnic group' and their date of birth
# Get informations about their studies
queryString = """
SELECT ?educatedAt ?name
WHERE {
   # ?poet wdt:P106 wd:Q49757 .     #BGP for poet
   # ?poet wdt:P172 wd:Q50001 .     #BGP for 'Italians'
   
   # ?poet wdt:P69 ?educatedAt .    #BGP for educated at
   # ?educatedAt wdt:P31 wd:Q3918.  #BGP for universities
   
   # ?educatedAt sc:name ?name.
}
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('educatedAt', 'http://www.wikidata.org/entity/Q1243705'), ('name', 'University of Modena and Reggio Emilia')]
# [('educatedAt', 'http://www.wikidata.org/entity/Q219317'), ('name', 'University of Pavia')]
# [('educatedAt', 'http://www.wikidata.org/entity/Q193510'), ('name', 'University of Padua')]
# [('educatedAt', 'http://www.wikidata.org/entity/Q193510'), ('name', 'University of Padua')]
# [('educatedAt', 'http://www.wikidata.org/entity/Q193510'), ('name', 'University of Padua')]
# [('educatedAt', 'http://www.wikidata.org/entity/Q193510'), ('name', 'University of Padua')]
# [('educatedAt', 'http://www.wikidata.org/entity/Q820887'), ('name', 'University of Florence')]
# [('educatedAt', 'http://www.wikidata.org/entity/Q820887'), ('name', 'University of Florence')]
# [('educatedAt', 'http://www.wikidata.org/entity/Q955609'), ('name', 'University of Ferrara')]
# [('educatedAt', 'http://www.wikidata.org/entity/Q593321'), ('name', 'University of Genoa')]
# [('educatedAt', 'http://www.wikidata.org/entity/Q593321'), ('name', 'University of Genoa')]
# [('educatedAt', 'http://www.wikidata.org/entity/Q645663'), ('name', 'University of Pisa')]
# 12

# %%
# Get all subjects that have 'poet' as 'occupation' and 'Italians' as 'ethnic group' and their date of birth
# Get informations about their university
queryString = """
SELECT DISTINCT ?educatedAt ?name
WHERE {
   # ?poet wdt:P106 wd:Q49757 .     #BGP for poet
   # ?poet wdt:P172 wd:Q50001 .     #BGP for 'Italians'
   
   # ?poet wdt:P69 ?educatedAt .    #BGP for educated at
   # ?educatedAt wdt:P31 wd:Q3918.  #BGP for universities
   
   # ?educatedAt sc:name ?name.
}
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('educatedAt', 'http://www.wikidata.org/entity/Q1243705'), ('name', 'University of Modena and Reggio Emilia')]
# [('educatedAt', 'http://www.wikidata.org/entity/Q219317'), ('name', 'University of Pavia')]
# [('educatedAt', 'http://www.wikidata.org/entity/Q193510'), ('name', 'University of Padua')]
# [('educatedAt', 'http://www.wikidata.org/entity/Q820887'), ('name', 'University of Florence')]
# [('educatedAt', 'http://www.wikidata.org/entity/Q955609'), ('name', 'University of Ferrara')]
# [('educatedAt', 'http://www.wikidata.org/entity/Q593321'), ('name', 'University of Genoa')]
# [('educatedAt', 'http://www.wikidata.org/entity/Q645663'), ('name', 'University of Pisa')]
# 7

# %%
# Get all subjects that have 'poet' as 'occupation' and 'Italians' as 'ethnic group' and their date of birth
# Get informations about the university in which they conduct their university studies
queryString = """
SELECT DISTINCT ?uni ?name
WHERE {
   # ?poet wdt:P106 wd:Q49757 .     #BGP for poet
   # ?poet wdt:P172 wd:Q50001 .     #BGP for 'Italians'
   
   # ?poet wdt:P69 ?uni .    #BGP for educated at
   # ?uni wdt:P31 wd:Q3918.  #BGP for universities
   # ?uni wdt:P17 wd:Q38.    #BGP to check that the univeristy is in Italy
   
   # ?uni sc:name ?name.
}
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('uni', 'http://www.wikidata.org/entity/Q1243705'), ('name', 'University of Modena and Reggio Emilia')]
# [('uni', 'http://www.wikidata.org/entity/Q219317'), ('name', 'University of Pavia')]
# [('uni', 'http://www.wikidata.org/entity/Q193510'), ('name', 'University of Padua')]
# [('uni', 'http://www.wikidata.org/entity/Q820887'), ('name', 'University of Florence')]
# [('uni', 'http://www.wikidata.org/entity/Q955609'), ('name', 'University of Ferrara')]
# [('uni', 'http://www.wikidata.org/entity/Q593321'), ('name', 'University of Genoa')]
# [('uni', 'http://www.wikidata.org/entity/Q645663'), ('name', 'University of Pisa')]
# 7

# %%
# Get all subjects that have 'poet' as 'occupation' and 'Italians' as 'ethnic group' and their date of birth
# Get informations about the city in which they conduct their university studies
queryString = """
SELECT DISTINCT ?city ?name
WHERE {
   # ?poet wdt:P106 wd:Q49757 .     #BGP for poet
   # ?poet wdt:P172 wd:Q50001 .     #BGP for 'Italians'
   
   # ?poet wdt:P69 ?uni .             #BGP for educated at
   # ?uni wdt:P31 wd:Q3918.           #BGP for universities
   # ?uni wdt:P17 wd:Q38.             #BGP to check that the univeristy is in Italy
   # ?uni wdt:P131 ?city.             #BGP to retieve the city 
   
   # ?city sc:name ?name.
}
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('city', 'http://www.wikidata.org/entity/Q1449'), ('name', 'Genoa')]
# [('city', 'http://www.wikidata.org/entity/Q13362'), ('name', 'Ferrara')]
# [('city', 'http://www.wikidata.org/entity/Q13375'), ('name', 'Pisa')]
# [('city', 'http://www.wikidata.org/entity/Q2044'), ('name', 'Florence')]
# [('city', 'http://www.wikidata.org/entity/Q6259'), ('name', 'Pavia')]
# [('city', 'http://www.wikidata.org/entity/Q279'), ('name', 'Modena')]
# [('city', 'http://www.wikidata.org/entity/Q617'), ('name', 'Padua')]
# 7

# %%
# Get info about public university
queryString = """
SELECT DISTINCT ?p ?name
WHERE {
    wd:Q875538 ?p ?o .
    # ?p sc:name ?name.
}
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P101'), ('name', 'field of work')]
# [('p', 'http://www.wikidata.org/prop/direct/P1149'), ('name', 'Library of Congress Classification')]
# [('p', 'http://www.wikidata.org/prop/direct/P18'), ('name', 'image')]
# [('p', 'http://www.wikidata.org/prop/direct/P1889'), ('name', 'different from')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('name', 'properties for this type')]
# [('p', 'http://www.wikidata.org/prop/direct/P2163'), ('name', 'FAST ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P244'), ('name', 'Library of Congress authority ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2581'), ('name', 'BabelNet ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('name', 'subclass of')]
# [('p', 'http://www.wikidata.org/prop/direct/P3417'), ('name', 'Quora topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P349'), ('name', 'National Diet Library ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P373'), ('name', 'Commons category')]
# [('p', 'http://www.wikidata.org/prop/direct/P3847'), ('name', 'Open Library subject ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P461'), ('name', 'opposite of')]
# [('p', 'http://www.wikidata.org/prop/direct/P646'), ('name', 'Freebase ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8408'), ('name', 'KBpedia ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P910'), ('name', "topic's main category")]
# 17

# %%
# Get info about public university
queryString = """
SELECT DISTINCT ?o ?name
WHERE {
    wd:Q875538 wdt:P279 ?o .
    # ?o sc:name ?name.
}
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('o', 'http://www.wikidata.org/entity/Q23002037'), ('name', 'public educational institution')]
# [('o', 'http://www.wikidata.org/entity/Q3918'), ('name', 'university')]
# 2

# %%
# Get all subjects that have 'poet' as 'occupation' and 'Italians' as 'ethnic group' and their date of birth
# Get informations about the city in which they conduct their university studies
queryString = """
SELECT DISTINCT ?uni ?name
WHERE {
   # ?poet wdt:P106 wd:Q49757 .     #BGP for poet
   # ?poet wdt:P172 wd:Q50001 .     #BGP for 'Italians'
   
   # ?poet wdt:P69 ?uni .                  #BGP for educated at
   
   # ?uni (wdt:P31)|(wdt:P279+) wd:Q3918.  #BGP for universities (missing 'Sapienza' public university)
   
   # ?uni sc:name ?name.
}
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('uni', 'http://www.wikidata.org/entity/Q1243705'), ('name', 'University of Modena and Reggio Emilia')]
# [('uni', 'http://www.wikidata.org/entity/Q219317'), ('name', 'University of Pavia')]
# [('uni', 'http://www.wikidata.org/entity/Q193510'), ('name', 'University of Padua')]
# [('uni', 'http://www.wikidata.org/entity/Q820887'), ('name', 'University of Florence')]
# [('uni', 'http://www.wikidata.org/entity/Q955609'), ('name', 'University of Ferrara')]
# [('uni', 'http://www.wikidata.org/entity/Q593321'), ('name', 'University of Genoa')]
# [('uni', 'http://www.wikidata.org/entity/Q645663'), ('name', 'University of Pisa')]
# 7

# %%
# Get all universities in Italy
queryString = """
SELECT DISTINCT ?uni ?name
WHERE {
    # ?uni wdt:P31 wd:Q3918. #BGP for instance of universtity
    # ?uni wdt:P17 wd:Q38.   #BGP for country 'Italy'
    # ?uni sc:name ?name.
}
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('uni', 'http://www.wikidata.org/entity/Q7209754'), ('name', 'Polimoda')]
# [('uni', 'http://www.wikidata.org/entity/Q1752540'), ('name', 'University of Calabria')]
# [('uni', 'http://www.wikidata.org/entity/Q3551649'), ('name', 'University of Campania Studies "Luigi Vanvitelli"')]
# [('uni', 'http://www.wikidata.org/entity/Q1546906'), ('name', "Ca' Foscari University of Venice")]
# [('uni', 'http://www.wikidata.org/entity/Q727492'), ('name', 'IUAV University of Venice')]
# [('uni', 'http://www.wikidata.org/entity/Q600924'), ('name', 'Foreigners University of Siena')]
# [('uni', 'http://www.wikidata.org/entity/Q7198162'), ('name', 'Pisa University System')]
# [('uni', 'http://www.wikidata.org/entity/Q1780458'), ('name', 'Tuscia University')]
# [('uni', 'http://www.wikidata.org/entity/Q1440288'), ('name', 'Università Campus Bio-Medico')]
# [('uni', 'http://www.wikidata.org/entity/Q1245999'), ('name', 'University of Siena')]
# [('uni', 'http://www.wikidata.org/entity/Q2297486'), ('name', 'Università degli Studi Roma Tre')]
# [('uni', 'http://www.wikidata.org/entity/Q1807942'), ('name', 'Pontifical University Antonianum')]
# [('uni', 'http://www.wikidata.org/entity/Q2307935'), ('name', 'University of Udine')]
# [('uni', 'http://www.wikidata.org/entity/Q46210'), ('name', 'University of Milan')]
# [('uni', 'http://www.wikidata.org/entity/Q748085'), ('name', 'University of Perugia')]
# [('uni', 'http://www.wikidata.org/entity/Q1231433'), ('name', 'Free University of Bozen-Bolzano')]
# [('uni', 'http://www.wikidata.org/entity/Q181410'), ('name', 'Accademia Nazionale di Santa Cecilia')]
# [('uni', 'http://www.wikidata.org/entity/Q1243705'), ('name', 'University of Modena and Reggio Emilia')]
# [('uni', 'http://www.wikidata.org/entity/Q2119752'), ('name', 'University of Urbino')]
# [('uni', 'http://www.wikidata.org/entity/Q219317'), ('name', 'University of Pavia')]
# [('uni', 'http://www.wikidata.org/entity/Q1245318'), ('name', 'University of Messina')]
# [('uni', 'http://www.wikidata.org/entity/Q2822439'), ('name', "Accademia Nazionale d'Arte Drammatica Silvio D'Amico")]
# [('uni', 'http://www.wikidata.org/entity/Q930528'), ('name', 'University of Trento')]
# [('uni', 'http://www.wikidata.org/entity/Q1781263'), ('name', 'University of Brescia')]
# [('uni', 'http://www.wikidata.org/entity/Q1742507'), ('name', 'University of Macerata')]
# [('uni', 'http://www.wikidata.org/entity/Q2067315'), ('name', 'University of Cagliari')]
# [('uni', 'http://www.wikidata.org/entity/Q193510'), ('name', 'University of Padua')]
# [('uni', 'http://www.wikidata.org/entity/Q229022'), ('name', 'Università Cattolica del Sacro Cuore')]
# [('uni', 'http://www.wikidata.org/entity/Q499911'), ('name', 'University of Turin')]
# [('uni', 'http://www.wikidata.org/entity/Q820887'), ('name', 'University of Florence')]
# [('uni', 'http://www.wikidata.org/entity/Q955609'), ('name', 'University of Ferrara')]
# [('uni', 'http://www.wikidata.org/entity/Q593321'), ('name', 'University of Genoa')]
# [('uni', 'http://www.wikidata.org/entity/Q779549'), ('name', 'Università per Stranieri di Perugia')]
# [('uni', 'http://www.wikidata.org/entity/Q1031803'), ('name', 'Tor Vergata University of Rome')]
# [('uni', 'http://www.wikidata.org/entity/Q427141'), ('name', 'Ghislieri College')]
# [('uni', 'http://www.wikidata.org/entity/Q1632525'), ('name', 'Naples Eastern University')]
# [('uni', 'http://www.wikidata.org/entity/Q176473'), ('name', 'Pontifical Oriental Institute')]
# [('uni', 'http://www.wikidata.org/entity/Q645663'), ('name', 'University of Pisa')]
# [('uni', 'http://www.wikidata.org/entity/Q392897'), ('name', 'Politecnico di Torino')]
# [('uni', 'http://www.wikidata.org/entity/Q470997'), ('name', 'Pontificio Ateneo Sant Anselmo')]
# [('uni', 'http://www.wikidata.org/entity/Q532822'), ('name', 'University of Sassari')]
# [('uni', 'http://www.wikidata.org/entity/Q691851'), ('name', 'University of Naples Federico II')]
# [('uni', 'http://www.wikidata.org/entity/Q2032536'), ('name', 'Pontifical Urbaniana University')]
# [('uni', 'http://www.wikidata.org/entity/Q1248821'), ('name', 'University of Catania')]
# [('uni', 'http://www.wikidata.org/entity/Q1641504'), ('name', 'University of Palermo')]
# [('uni', 'http://www.wikidata.org/entity/Q1758474'), ('name', 'University of Parma')]
# [('uni', 'http://www.wikidata.org/entity/Q1073674'), ('name', 'University of Milan-Bicocca')]
# [('uni', 'http://www.wikidata.org/entity/Q1236136'), ('name', 'University of Bari')]
# [('uni', 'http://www.wikidata.org/entity/Q676817'), ('name', 'University of Camerino')]
# [('uni', 'http://www.wikidata.org/entity/Q3551506'), ('name', 'Vita-Salute San Raffaele University')]
# [('uni', 'http://www.wikidata.org/entity/Q3803694'), ('name', 'Scuola Superiore Studi Pavia IUSS')]
# [('uni', 'http://www.wikidata.org/entity/Q6232900'), ('name', 'John Felice Rome Center')]
# [('uni', 'http://www.wikidata.org/entity/Q2523033'), ('name', 'University of Gastronomic Sciences')]
# [('uni', 'http://www.wikidata.org/entity/Q3551385'), ('name', 'University Carlo Cattaneo')]
# [('uni', 'http://www.wikidata.org/entity/Q1168859'), ('name', 'Accademia Albertina')]
# [('uni', 'http://www.wikidata.org/entity/Q2261128'), ('name', "D'Annunzio University of Chieti–Pescara")]
# [('uni', 'http://www.wikidata.org/entity/Q1084409'), ('name', 'Marche Polytechnic University')]
# [('uni', 'http://www.wikidata.org/entity/Q2531629'), ('name', 'University of Verona')]
# [('uni', 'http://www.wikidata.org/entity/Q64153182'), ('name', 'Monash University Prato')]
# [('uni', 'http://www.wikidata.org/entity/Q4654029'), ('name', 'ASAG – Postgraduate School of Psychology Agostino Gemelli')]
# [('uni', 'http://www.wikidata.org/entity/Q4671475'), ('name', 'Academy of Fine Arts, Verona')]
# [('uni', 'http://www.wikidata.org/entity/Q2424299'), ('name', 'International School for Advanced Studies')]
# [('uni', 'http://www.wikidata.org/entity/Q1235561'), ('name', 'University of Eastern Piedmont')]
# [('uni', 'http://www.wikidata.org/entity/Q338481'), ('name', 'Academy of Fine Arts')]
# [('uni', 'http://www.wikidata.org/entity/Q1378099'), ('name', 'European University Institute')]
# [('uni', 'http://www.wikidata.org/entity/Q6039434'), ('name', 'Institute for International Political Studies')]
# [('uni', 'http://www.wikidata.org/entity/Q1934874'), ('name', 'Military Academy of Modena')]
# [('uni', 'http://www.wikidata.org/entity/Q35326177'), ('name', 'Facoltà di Architettura di Torino')]
# [('uni', 'http://www.wikidata.org/entity/Q35326590'), ('name', 'Palazzo Nuovo')]
# [('uni', 'http://www.wikidata.org/entity/Q266537'), ('name', 'Magna Græcia University')]
# [('uni', 'http://www.wikidata.org/entity/Q617446'), ('name', 'University of Foggia')]
# [('uni', 'http://www.wikidata.org/entity/Q469446'), ('name', 'American University of Rome')]
# [('uni', 'http://www.wikidata.org/entity/Q1309998'), ('name', 'University of Insubria')]
# [('uni', 'http://www.wikidata.org/entity/Q1230902'), ('name', 'University of Salento')]
# [('uni', 'http://www.wikidata.org/entity/Q1494671'), ('name', "University of L'Aquila")]
# [('uni', 'http://www.wikidata.org/entity/Q1780716'), ('name', 'Mediterranea University of Reggio Calabria')]
# [('uni', 'http://www.wikidata.org/entity/Q59386762'), ('name', 'Humanitas University')]
# [('uni', 'http://www.wikidata.org/entity/Q39918611'), ('name', 'Universita degli Studi Di Cagliari Cittadella Universitaria')]
# [('uni', 'http://www.wikidata.org/entity/Q3682946'), ('name', 'Collegio Carlo Alberto')]
# [('uni', 'http://www.wikidata.org/entity/Q1274578'), ('name', 'Università europea di Roma')]
# [('uni', 'http://www.wikidata.org/entity/Q1054324'), ('name', 'Polytechnic University of Bari')]
# [('uni', 'http://www.wikidata.org/entity/Q2319621'), ('name', "Università della Valle d'Aosta")]
# [('uni', 'http://www.wikidata.org/entity/Q3551650'), ('name', 'Parthenope University of Naples')]
# [('uni', 'http://www.wikidata.org/entity/Q1093340'), ('name', 'University of Molise')]
# [('uni', 'http://www.wikidata.org/entity/Q4005942'), ('name', 'Università degli Studi di Roma "Unitelma Sapienza"')]
# [('uni', 'http://www.wikidata.org/entity/Q2120406'), ('name', 'Pontifical Institute of Christian Archaeology')]
# [('uni', 'http://www.wikidata.org/entity/Q1481995'), ('name', 'Kore University of Enna')]
# [('uni', 'http://www.wikidata.org/entity/Q3551769'), ('name', 'University of Sannio')]
# [('uni', 'http://www.wikidata.org/entity/Q3152661'), ('name', 'Foro Italico University of Rome')]
# [('uni', 'http://www.wikidata.org/entity/Q504263'), ('name', 'University of Cassino')]
# [('uni', 'http://www.wikidata.org/entity/Q3833046'), ('name', 'Link Campus University')]
# [('uni', 'http://www.wikidata.org/entity/Q3551499'), ('name', 'Suor Orsola Benincasa University of Naples')]
# [('uni', 'http://www.wikidata.org/entity/Q1314405'), ('name', 'John Cabot University')]
# [('uni', 'http://www.wikidata.org/entity/Q29915035'), ('name', 'Free Academy of Fine Arts (LABA)')]
# [('uni', 'http://www.wikidata.org/entity/Q107496653'), ('name', 'Polo Universitario Grossetano')]
# [('uni', 'http://www.wikidata.org/entity/Q3943517'), ('name', 'SDA Bocconi School of Management')]
# [('uni', 'http://www.wikidata.org/entity/Q3604024'), ('name', 'Accademia di Belle Arti di Perugia')]
# [('uni', 'http://www.wikidata.org/entity/Q5458567'), ('name', 'Fleming College Florence')]
# [('uni', 'http://www.wikidata.org/entity/Q3831607'), ('name', 'Libera Università Mediterranea')]
# [('uni', 'http://www.wikidata.org/entity/Q1127590'), ('name', 'Consorzio ICoN')]
# [('uni', 'http://www.wikidata.org/entity/Q7743414'), ('name', 'The Johns Hopkins University SAIS Bologna Center')]
# [('uni', 'http://www.wikidata.org/entity/Q4652396'), ('name', 'ALMED – Postgraduate School of Media Communications and Performing Arts')]
# [('uni', 'http://www.wikidata.org/entity/Q4005949'), ('name', 'Università telematica internazionale UniNettuno')]
# [('uni', 'http://www.wikidata.org/entity/Q2905216'), ('name', 'Venice International University')]
# [('uni', 'http://www.wikidata.org/entity/Q3996914'), ('name', 'Touro University Rome')]
# [('uni', 'http://www.wikidata.org/entity/Q1054341'), ('name', 'Centre for Studies on Federalism')]
# [('uni', 'http://www.wikidata.org/entity/Q15261139'), ('name', 'National Observatory of Outsider Art')]
# [('uni', 'http://www.wikidata.org/entity/Q84035409'), ('name', 'Università dei cani da tartufo')]
# [('uni', 'http://www.wikidata.org/entity/Q16949007'), ('name', "Lorenzo de' Medici School")]
# [('uni', 'http://www.wikidata.org/entity/Q14539971'), ('name', 'Accademia italiana')]
# [('uni', 'http://www.wikidata.org/entity/Q4652448'), ('name', 'ALTIS – Postgraduate School Business & Society')]
# [('uni', 'http://www.wikidata.org/entity/Q4654207'), ('name', 'ASERI – Postgraduate School of Economics and International Relations')]
# [('uni', 'http://www.wikidata.org/entity/Q45745121'), ('name', 'Istituto di Moda Burgo')]
# [('uni', 'http://www.wikidata.org/entity/Q3604040'), ('name', 'Accademia di belle arti europea dei media')]
# [('uni', 'http://www.wikidata.org/entity/Q29366803'), ('name', 'Rome Business School, Rome')]
# [('uni', 'http://www.wikidata.org/entity/Q3270465'), ('name', 'University of Vicenza')]
# [('uni', 'http://www.wikidata.org/entity/Q4005936'), ('name', 'University for Foreigners "Dante Alighieri" of Reggio Calabria')]
# [('uni', 'http://www.wikidata.org/entity/Q7896507'), ('name', 'University of Turin, Faculty of Law')]
# [('uni', 'http://www.wikidata.org/entity/Q7439503'), ('name', 'Scuola Italiana Design')]
# [('uni', 'http://www.wikidata.org/entity/Q104628992'), ('name', 'Istituto Superiore per Imprenditori e Dirigenti di Azienda')]
# [('uni', 'http://www.wikidata.org/entity/Q3738249'), ('name', 'Theological University of Northern Italy – Turin Campus')]
# [('uni', 'http://www.wikidata.org/entity/Q56254848'), ('name', 'Palazzo Venier delle Torreselle')]
# [('uni', 'http://www.wikidata.org/entity/Q35326042'), ('name', 'Antiche Vetrerie')]
# [('uni', 'http://www.wikidata.org/entity/Q27926167'), ('name', 'Centre for Child Protection')]
# [('uni', 'http://www.wikidata.org/entity/Q7825120'), ('name', 'Toppo Wassermann College')]
# [('uni', 'http://www.wikidata.org/entity/Q7854950'), ('name', 'Turin School of Development')]
# [('uni', 'http://www.wikidata.org/entity/Q3699300'), ('name', 'University of Ragusa')]
# [('uni', 'http://www.wikidata.org/entity/Q107429566'), ('name', 'ICA Istituto Contemporaneo per le Arti')]
# [('uni', 'http://www.wikidata.org/entity/Q3747151'), ('name', 'CUOA Foundation')]
# [('uni', 'http://www.wikidata.org/entity/Q5774694'), ('name', 'History Curriculum at the Gregorian University')]
# [('uni', 'http://www.wikidata.org/entity/Q4654068'), ('name', 'ASA – Postgraduate School of Environmental Studies')]
# [('uni', 'http://www.wikidata.org/entity/Q7391137'), ('name', 'SMEA – Postgraduate School of Agricultural and Food Economics')]
# [('uni', 'http://www.wikidata.org/entity/Q3682991'), ('name', 'Collegio Superiore di Bologna')]
# [('uni', 'http://www.wikidata.org/entity/Q3953349'), ('name', 'Scuola Politecnica di Design')]
# [('uni', 'http://www.wikidata.org/entity/Q3967519'), ('name', 'St. John International University')]
# [('uni', 'http://www.wikidata.org/entity/Q6092782'), ('name', 'Italian Institute of Human Sciences')]
# [('uni', 'http://www.wikidata.org/entity/Q6505336'), ('name', 'Lay Centre at Foyer Unitas')]
# [('uni', 'http://www.wikidata.org/entity/Q4652446'), ('name', 'ALTEMS – Postgraduate School of Health Economics and Management')]
# [('uni', 'http://www.wikidata.org/entity/Q16967405'), ('name', 'Pontifical universities in Rome')]
# [('uni', 'http://www.wikidata.org/entity/Q35326338'), ('name', 'Ingegneria Mesiano')]
# [('uni', 'http://www.wikidata.org/entity/Q35326604'), ('name', 'Palazzo Venturi')]
# [('uni', 'http://www.wikidata.org/entity/Q35326663'), ('name', 'School of Mathematics, Physics e Natural Sciences')]
# 142

# %%
# Get universities and public universities in Italy
queryString = """
SELECT DISTINCT ?uni ?name ?class
WHERE {
    # ?uni wdt:P17 wd:Q38.         #BGP for country 'Italy'
    # ?uni wdt:P31 ?of.            #BGP for instance of
    FILTER(?of = wd:Q3918 || ?of = wd:Q875538) #filter universities and public universities
    # ?uni sc:name ?name.
}
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('uni', 'http://www.wikidata.org/entity/Q7209754'), ('name', 'Polimoda')]
# [('uni', 'http://www.wikidata.org/entity/Q1752540'), ('name', 'University of Calabria')]
# [('uni', 'http://www.wikidata.org/entity/Q3551649'), ('name', 'University of Campania Studies "Luigi Vanvitelli"')]
# [('uni', 'http://www.wikidata.org/entity/Q1546906'), ('name', "Ca' Foscari University of Venice")]
# [('uni', 'http://www.wikidata.org/entity/Q727492'), ('name', 'IUAV University of Venice')]
# [('uni', 'http://www.wikidata.org/entity/Q600924'), ('name', 'Foreigners University of Siena')]
# [('uni', 'http://www.wikidata.org/entity/Q7198162'), ('name', 'Pisa University System')]
# [('uni', 'http://www.wikidata.org/entity/Q1780458'), ('name', 'Tuscia University')]
# [('uni', 'http://www.wikidata.org/entity/Q1440288'), ('name', 'Università Campus Bio-Medico')]
# [('uni', 'http://www.wikidata.org/entity/Q1245999'), ('name', 'University of Siena')]
# [('uni', 'http://www.wikidata.org/entity/Q2297486'), ('name', 'Università degli Studi Roma Tre')]
# [('uni', 'http://www.wikidata.org/entity/Q1807942'), ('name', 'Pontifical University Antonianum')]
# [('uni', 'http://www.wikidata.org/entity/Q2307935'), ('name', 'University of Udine')]
# [('uni', 'http://www.wikidata.org/entity/Q46210'), ('name', 'University of Milan')]
# [('uni', 'http://www.wikidata.org/entity/Q748085'), ('name', 'University of Perugia')]
# [('uni', 'http://www.wikidata.org/entity/Q1231433'), ('name', 'Free University of Bozen-Bolzano')]
# [('uni', 'http://www.wikidata.org/entity/Q181410'), ('name', 'Accademia Nazionale di Santa Cecilia')]
# [('uni', 'http://www.wikidata.org/entity/Q1243705'), ('name', 'University of Modena and Reggio Emilia')]
# [('uni', 'http://www.wikidata.org/entity/Q2119752'), ('name', 'University of Urbino')]
# [('uni', 'http://www.wikidata.org/entity/Q219317'), ('name', 'University of Pavia')]
# [('uni', 'http://www.wikidata.org/entity/Q1245318'), ('name', 'University of Messina')]
# [('uni', 'http://www.wikidata.org/entity/Q2822439'), ('name', "Accademia Nazionale d'Arte Drammatica Silvio D'Amico")]
# [('uni', 'http://www.wikidata.org/entity/Q930528'), ('name', 'University of Trento')]
# [('uni', 'http://www.wikidata.org/entity/Q1781263'), ('name', 'University of Brescia')]
# [('uni', 'http://www.wikidata.org/entity/Q1742507'), ('name', 'University of Macerata')]
# [('uni', 'http://www.wikidata.org/entity/Q2067315'), ('name', 'University of Cagliari')]
# [('uni', 'http://www.wikidata.org/entity/Q193510'), ('name', 'University of Padua')]
# [('uni', 'http://www.wikidata.org/entity/Q229022'), ('name', 'Università Cattolica del Sacro Cuore')]
# [('uni', 'http://www.wikidata.org/entity/Q499911'), ('name', 'University of Turin')]
# [('uni', 'http://www.wikidata.org/entity/Q820887'), ('name', 'University of Florence')]
# [('uni', 'http://www.wikidata.org/entity/Q955609'), ('name', 'University of Ferrara')]
# [('uni', 'http://www.wikidata.org/entity/Q593321'), ('name', 'University of Genoa')]
# [('uni', 'http://www.wikidata.org/entity/Q779549'), ('name', 'Università per Stranieri di Perugia')]
# [('uni', 'http://www.wikidata.org/entity/Q1031803'), ('name', 'Tor Vergata University of Rome')]
# [('uni', 'http://www.wikidata.org/entity/Q427141'), ('name', 'Ghislieri College')]
# [('uni', 'http://www.wikidata.org/entity/Q1632525'), ('name', 'Naples Eastern University')]
# [('uni', 'http://www.wikidata.org/entity/Q176473'), ('name', 'Pontifical Oriental Institute')]
# [('uni', 'http://www.wikidata.org/entity/Q645663'), ('name', 'University of Pisa')]
# [('uni', 'http://www.wikidata.org/entity/Q392897'), ('name', 'Politecnico di Torino')]
# [('uni', 'http://www.wikidata.org/entity/Q470997'), ('name', 'Pontificio Ateneo Sant Anselmo')]
# [('uni', 'http://www.wikidata.org/entity/Q532822'), ('name', 'University of Sassari')]
# [('uni', 'http://www.wikidata.org/entity/Q691851'), ('name', 'University of Naples Federico II')]
# [('uni', 'http://www.wikidata.org/entity/Q2032536'), ('name', 'Pontifical Urbaniana University')]
# [('uni', 'http://www.wikidata.org/entity/Q1248821'), ('name', 'University of Catania')]
# [('uni', 'http://www.wikidata.org/entity/Q1641504'), ('name', 'University of Palermo')]
# [('uni', 'http://www.wikidata.org/entity/Q1758474'), ('name', 'University of Parma')]
# [('uni', 'http://www.wikidata.org/entity/Q1073674'), ('name', 'University of Milan-Bicocca')]
# [('uni', 'http://www.wikidata.org/entity/Q1236136'), ('name', 'University of Bari')]
# [('uni', 'http://www.wikidata.org/entity/Q676817'), ('name', 'University of Camerino')]
# [('uni', 'http://www.wikidata.org/entity/Q3551506'), ('name', 'Vita-Salute San Raffaele University')]
# [('uni', 'http://www.wikidata.org/entity/Q3803694'), ('name', 'Scuola Superiore Studi Pavia IUSS')]
# [('uni', 'http://www.wikidata.org/entity/Q6232900'), ('name', 'John Felice Rome Center')]
# [('uni', 'http://www.wikidata.org/entity/Q2523033'), ('name', 'University of Gastronomic Sciences')]
# [('uni', 'http://www.wikidata.org/entity/Q3551385'), ('name', 'University Carlo Cattaneo')]
# [('uni', 'http://www.wikidata.org/entity/Q1168859'), ('name', 'Accademia Albertina')]
# [('uni', 'http://www.wikidata.org/entity/Q2261128'), ('name', "D'Annunzio University of Chieti–Pescara")]
# [('uni', 'http://www.wikidata.org/entity/Q1084409'), ('name', 'Marche Polytechnic University')]
# [('uni', 'http://www.wikidata.org/entity/Q2531629'), ('name', 'University of Verona')]
# [('uni', 'http://www.wikidata.org/entity/Q64153182'), ('name', 'Monash University Prato')]
# [('uni', 'http://www.wikidata.org/entity/Q4654029'), ('name', 'ASAG – Postgraduate School of Psychology Agostino Gemelli')]
# [('uni', 'http://www.wikidata.org/entity/Q4671475'), ('name', 'Academy of Fine Arts, Verona')]
# [('uni', 'http://www.wikidata.org/entity/Q2424299'), ('name', 'International School for Advanced Studies')]
# [('uni', 'http://www.wikidata.org/entity/Q1235561'), ('name', 'University of Eastern Piedmont')]
# [('uni', 'http://www.wikidata.org/entity/Q338481'), ('name', 'Academy of Fine Arts')]
# [('uni', 'http://www.wikidata.org/entity/Q1378099'), ('name', 'European University Institute')]
# [('uni', 'http://www.wikidata.org/entity/Q6039434'), ('name', 'Institute for International Political Studies')]
# [('uni', 'http://www.wikidata.org/entity/Q1934874'), ('name', 'Military Academy of Modena')]
# [('uni', 'http://www.wikidata.org/entity/Q35326177'), ('name', 'Facoltà di Architettura di Torino')]
# [('uni', 'http://www.wikidata.org/entity/Q35326590'), ('name', 'Palazzo Nuovo')]
# [('uni', 'http://www.wikidata.org/entity/Q266537'), ('name', 'Magna Græcia University')]
# [('uni', 'http://www.wikidata.org/entity/Q617446'), ('name', 'University of Foggia')]
# [('uni', 'http://www.wikidata.org/entity/Q469446'), ('name', 'American University of Rome')]
# [('uni', 'http://www.wikidata.org/entity/Q1309998'), ('name', 'University of Insubria')]
# [('uni', 'http://www.wikidata.org/entity/Q1230902'), ('name', 'University of Salento')]
# [('uni', 'http://www.wikidata.org/entity/Q1494671'), ('name', "University of L'Aquila")]
# [('uni', 'http://www.wikidata.org/entity/Q1780716'), ('name', 'Mediterranea University of Reggio Calabria')]
# [('uni', 'http://www.wikidata.org/entity/Q59386762'), ('name', 'Humanitas University')]
# [('uni', 'http://www.wikidata.org/entity/Q39918611'), ('name', 'Universita degli Studi Di Cagliari Cittadella Universitaria')]
# [('uni', 'http://www.wikidata.org/entity/Q3682946'), ('name', 'Collegio Carlo Alberto')]
# [('uni', 'http://www.wikidata.org/entity/Q1274578'), ('name', 'Università europea di Roma')]
# [('uni', 'http://www.wikidata.org/entity/Q1054324'), ('name', 'Polytechnic University of Bari')]
# [('uni', 'http://www.wikidata.org/entity/Q2319621'), ('name', "Università della Valle d'Aosta")]
# [('uni', 'http://www.wikidata.org/entity/Q3551650'), ('name', 'Parthenope University of Naples')]
# [('uni', 'http://www.wikidata.org/entity/Q1093340'), ('name', 'University of Molise')]
# [('uni', 'http://www.wikidata.org/entity/Q4005942'), ('name', 'Università degli Studi di Roma "Unitelma Sapienza"')]
# [('uni', 'http://www.wikidata.org/entity/Q2120406'), ('name', 'Pontifical Institute of Christian Archaeology')]
# [('uni', 'http://www.wikidata.org/entity/Q1481995'), ('name', 'Kore University of Enna')]
# [('uni', 'http://www.wikidata.org/entity/Q3551769'), ('name', 'University of Sannio')]
# [('uni', 'http://www.wikidata.org/entity/Q3152661'), ('name', 'Foro Italico University of Rome')]
# [('uni', 'http://www.wikidata.org/entity/Q504263'), ('name', 'University of Cassino')]
# [('uni', 'http://www.wikidata.org/entity/Q3833046'), ('name', 'Link Campus University')]
# [('uni', 'http://www.wikidata.org/entity/Q3551499'), ('name', 'Suor Orsola Benincasa University of Naples')]
# [('uni', 'http://www.wikidata.org/entity/Q1314405'), ('name', 'John Cabot University')]
# [('uni', 'http://www.wikidata.org/entity/Q29915035'), ('name', 'Free Academy of Fine Arts (LABA)')]
# [('uni', 'http://www.wikidata.org/entity/Q107496653'), ('name', 'Polo Universitario Grossetano')]
# [('uni', 'http://www.wikidata.org/entity/Q3943517'), ('name', 'SDA Bocconi School of Management')]
# [('uni', 'http://www.wikidata.org/entity/Q3604024'), ('name', 'Accademia di Belle Arti di Perugia')]
# [('uni', 'http://www.wikidata.org/entity/Q5458567'), ('name', 'Fleming College Florence')]
# [('uni', 'http://www.wikidata.org/entity/Q3831607'), ('name', 'Libera Università Mediterranea')]
# [('uni', 'http://www.wikidata.org/entity/Q1127590'), ('name', 'Consorzio ICoN')]
# [('uni', 'http://www.wikidata.org/entity/Q7743414'), ('name', 'The Johns Hopkins University SAIS Bologna Center')]
# [('uni', 'http://www.wikidata.org/entity/Q4652396'), ('name', 'ALMED – Postgraduate School of Media Communications and Performing Arts')]
# [('uni', 'http://www.wikidata.org/entity/Q4005949'), ('name', 'Università telematica internazionale UniNettuno')]
# [('uni', 'http://www.wikidata.org/entity/Q2905216'), ('name', 'Venice International University')]
# [('uni', 'http://www.wikidata.org/entity/Q3996914'), ('name', 'Touro University Rome')]
# [('uni', 'http://www.wikidata.org/entity/Q1054341'), ('name', 'Centre for Studies on Federalism')]
# [('uni', 'http://www.wikidata.org/entity/Q15261139'), ('name', 'National Observatory of Outsider Art')]
# [('uni', 'http://www.wikidata.org/entity/Q84035409'), ('name', 'Università dei cani da tartufo')]
# [('uni', 'http://www.wikidata.org/entity/Q16949007'), ('name', "Lorenzo de' Medici School")]
# [('uni', 'http://www.wikidata.org/entity/Q14539971'), ('name', 'Accademia italiana')]
# [('uni', 'http://www.wikidata.org/entity/Q4652448'), ('name', 'ALTIS – Postgraduate School Business & Society')]
# [('uni', 'http://www.wikidata.org/entity/Q4654207'), ('name', 'ASERI – Postgraduate School of Economics and International Relations')]
# [('uni', 'http://www.wikidata.org/entity/Q45745121'), ('name', 'Istituto di Moda Burgo')]
# [('uni', 'http://www.wikidata.org/entity/Q3604040'), ('name', 'Accademia di belle arti europea dei media')]
# [('uni', 'http://www.wikidata.org/entity/Q29366803'), ('name', 'Rome Business School, Rome')]
# [('uni', 'http://www.wikidata.org/entity/Q3270465'), ('name', 'University of Vicenza')]
# [('uni', 'http://www.wikidata.org/entity/Q4005936'), ('name', 'University for Foreigners "Dante Alighieri" of Reggio Calabria')]
# [('uni', 'http://www.wikidata.org/entity/Q7896507'), ('name', 'University of Turin, Faculty of Law')]
# [('uni', 'http://www.wikidata.org/entity/Q7439503'), ('name', 'Scuola Italiana Design')]
# [('uni', 'http://www.wikidata.org/entity/Q104628992'), ('name', 'Istituto Superiore per Imprenditori e Dirigenti di Azienda')]
# [('uni', 'http://www.wikidata.org/entity/Q3738249'), ('name', 'Theological University of Northern Italy – Turin Campus')]
# [('uni', 'http://www.wikidata.org/entity/Q56254848'), ('name', 'Palazzo Venier delle Torreselle')]
# [('uni', 'http://www.wikidata.org/entity/Q35326042'), ('name', 'Antiche Vetrerie')]
# [('uni', 'http://www.wikidata.org/entity/Q27926167'), ('name', 'Centre for Child Protection')]
# [('uni', 'http://www.wikidata.org/entity/Q7825120'), ('name', 'Toppo Wassermann College')]
# [('uni', 'http://www.wikidata.org/entity/Q7854950'), ('name', 'Turin School of Development')]
# [('uni', 'http://www.wikidata.org/entity/Q3699300'), ('name', 'University of Ragusa')]
# [('uni', 'http://www.wikidata.org/entity/Q209344'), ('name', 'Sapienza University of Rome')]
# [('uni', 'http://www.wikidata.org/entity/Q1751060'), ('name', 'University of Trieste')]
# [('uni', 'http://www.wikidata.org/entity/Q1633215'), ('name', 'University of Salerno')]
# [('uni', 'http://www.wikidata.org/entity/Q3953222'), ('name', 'National Film School')]
# [('uni', 'http://www.wikidata.org/entity/Q131262'), ('name', 'University of Bologna')]
# [('uni', 'http://www.wikidata.org/entity/Q2303527'), ('name', 'University of Teramo')]
# [('uni', 'http://www.wikidata.org/entity/Q107429566'), ('name', 'ICA Istituto Contemporaneo per le Arti')]
# [('uni', 'http://www.wikidata.org/entity/Q3747151'), ('name', 'CUOA Foundation')]
# [('uni', 'http://www.wikidata.org/entity/Q5774694'), ('name', 'History Curriculum at the Gregorian University')]
# [('uni', 'http://www.wikidata.org/entity/Q4654068'), ('name', 'ASA – Postgraduate School of Environmental Studies')]
# [('uni', 'http://www.wikidata.org/entity/Q7391137'), ('name', 'SMEA – Postgraduate School of Agricultural and Food Economics')]
# [('uni', 'http://www.wikidata.org/entity/Q3682991'), ('name', 'Collegio Superiore di Bologna')]
# [('uni', 'http://www.wikidata.org/entity/Q3953349'), ('name', 'Scuola Politecnica di Design')]
# [('uni', 'http://www.wikidata.org/entity/Q3967519'), ('name', 'St. John International University')]
# [('uni', 'http://www.wikidata.org/entity/Q6092782'), ('name', 'Italian Institute of Human Sciences')]
# [('uni', 'http://www.wikidata.org/entity/Q6505336'), ('name', 'Lay Centre at Foyer Unitas')]
# [('uni', 'http://www.wikidata.org/entity/Q4652446'), ('name', 'ALTEMS – Postgraduate School of Health Economics and Management')]
# [('uni', 'http://www.wikidata.org/entity/Q16967405'), ('name', 'Pontifical universities in Rome')]
# [('uni', 'http://www.wikidata.org/entity/Q35326338'), ('name', 'Ingegneria Mesiano')]
# [('uni', 'http://www.wikidata.org/entity/Q35326604'), ('name', 'Palazzo Venturi')]
# [('uni', 'http://www.wikidata.org/entity/Q35326663'), ('name', 'School of Mathematics, Physics e Natural Sciences')]
# [('uni', 'http://www.wikidata.org/entity/Q45855'), ('name', 'University of Bergamo')]
# [('uni', 'http://www.wikidata.org/entity/Q1084383'), ('name', 'University of Basilicata')]
# 150

# %% [markdown]
# The university of Rome 'La Sapienza' not an instance of 'University' but is an instance of a sub class of 'University', so with this query I want to retrieve all instances (or instances of a sub class) of university

# %%
# Get all universities in Italy
queryString = """
SELECT DISTINCT ?uni ?name
WHERE {
    # ?uni wdt:P17 wd:Q38.             #BGP for country 'Italy'
    # ?uni wdt:P31/wdt:P279* wd:Q3918. #BGP for instance of university or a subclass
    # ?uni sc:name ?name.
}
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('uni', 'http://www.wikidata.org/entity/Q7209754'), ('name', 'Polimoda')]
# [('uni', 'http://www.wikidata.org/entity/Q1752540'), ('name', 'University of Calabria')]
# [('uni', 'http://www.wikidata.org/entity/Q3551649'), ('name', 'University of Campania Studies "Luigi Vanvitelli"')]
# [('uni', 'http://www.wikidata.org/entity/Q1546906'), ('name', "Ca' Foscari University of Venice")]
# [('uni', 'http://www.wikidata.org/entity/Q548435'), ('name', 'Pontifical University of the Holy Cross')]
# [('uni', 'http://www.wikidata.org/entity/Q498107'), ('name', 'Pontifical Institute of Arab and Islamic Studies')]
# [('uni', 'http://www.wikidata.org/entity/Q727492'), ('name', 'IUAV University of Venice')]
# [('uni', 'http://www.wikidata.org/entity/Q7228275'), ('name', 'Pontifical Roman Athenaeum S. Apollinare')]
# [('uni', 'http://www.wikidata.org/entity/Q600924'), ('name', 'Foreigners University of Siena')]
# [('uni', 'http://www.wikidata.org/entity/Q7198162'), ('name', 'Pisa University System')]
# [('uni', 'http://www.wikidata.org/entity/Q1780458'), ('name', 'Tuscia University')]
# [('uni', 'http://www.wikidata.org/entity/Q1440288'), ('name', 'Università Campus Bio-Medico')]
# [('uni', 'http://www.wikidata.org/entity/Q1245999'), ('name', 'University of Siena')]
# [('uni', 'http://www.wikidata.org/entity/Q2297486'), ('name', 'Università degli Studi Roma Tre')]
# [('uni', 'http://www.wikidata.org/entity/Q392904'), ('name', 'Politecnico di Milano')]
# [('uni', 'http://www.wikidata.org/entity/Q1807942'), ('name', 'Pontifical University Antonianum')]
# [('uni', 'http://www.wikidata.org/entity/Q2307935'), ('name', 'University of Udine')]
# [('uni', 'http://www.wikidata.org/entity/Q46210'), ('name', 'University of Milan')]
# [('uni', 'http://www.wikidata.org/entity/Q748085'), ('name', 'University of Perugia')]
# [('uni', 'http://www.wikidata.org/entity/Q1231433'), ('name', 'Free University of Bozen-Bolzano')]
# [('uni', 'http://www.wikidata.org/entity/Q181410'), ('name', 'Accademia Nazionale di Santa Cecilia')]
# [('uni', 'http://www.wikidata.org/entity/Q1243705'), ('name', 'University of Modena and Reggio Emilia')]
# [('uni', 'http://www.wikidata.org/entity/Q2119752'), ('name', 'University of Urbino')]
# [('uni', 'http://www.wikidata.org/entity/Q219317'), ('name', 'University of Pavia')]
# [('uni', 'http://www.wikidata.org/entity/Q1245318'), ('name', 'University of Messina')]
# [('uni', 'http://www.wikidata.org/entity/Q2822439'), ('name', "Accademia Nazionale d'Arte Drammatica Silvio D'Amico")]
# [('uni', 'http://www.wikidata.org/entity/Q930528'), ('name', 'University of Trento')]
# [('uni', 'http://www.wikidata.org/entity/Q1781263'), ('name', 'University of Brescia')]
# [('uni', 'http://www.wikidata.org/entity/Q1742507'), ('name', 'University of Macerata')]
# [('uni', 'http://www.wikidata.org/entity/Q2067315'), ('name', 'University of Cagliari')]
# [('uni', 'http://www.wikidata.org/entity/Q467025'), ('name', 'Pontifical Gregorian University')]
# [('uni', 'http://www.wikidata.org/entity/Q176473'), ('name', 'Pontifical Oriental Institute')]
# [('uni', 'http://www.wikidata.org/entity/Q475007'), ('name', 'Pontifical Lateran University')]
# [('uni', 'http://www.wikidata.org/entity/Q543289'), ('name', 'Salesian Pontifical University')]
# [('uni', 'http://www.wikidata.org/entity/Q392897'), ('name', 'Politecnico di Torino')]
# [('uni', 'http://www.wikidata.org/entity/Q470997'), ('name', 'Pontificio Ateneo Sant Anselmo')]
# [('uni', 'http://www.wikidata.org/entity/Q1277967'), ('name', 'Collegium Seraphicum - Rome')]
# [('uni', 'http://www.wikidata.org/entity/Q1504133'), ('name', 'Pontifical Athenaeum Regina Apostolorum')]
# [('uni', 'http://www.wikidata.org/entity/Q1054324'), ('name', 'Polytechnic University of Bari')]
# [('uni', 'http://www.wikidata.org/entity/Q1109156'), ('name', "Pontifical Institute Santa Maria dell' Anima")]
# [('uni', 'http://www.wikidata.org/entity/Q193510'), ('name', 'University of Padua')]
# [('uni', 'http://www.wikidata.org/entity/Q229022'), ('name', 'Università Cattolica del Sacro Cuore')]
# [('uni', 'http://www.wikidata.org/entity/Q499911'), ('name', 'University of Turin')]
# [('uni', 'http://www.wikidata.org/entity/Q820887'), ('name', 'University of Florence')]
# [('uni', 'http://www.wikidata.org/entity/Q955609'), ('name', 'University of Ferrara')]
# [('uni', 'http://www.wikidata.org/entity/Q593321'), ('name', 'University of Genoa')]
# [('uni', 'http://www.wikidata.org/entity/Q779549'), ('name', 'Università per Stranieri di Perugia')]
# [('uni', 'http://www.wikidata.org/entity/Q1031803'), ('name', 'Tor Vergata University of Rome')]
# [('uni', 'http://www.wikidata.org/entity/Q427141'), ('name', 'Ghislieri College')]
# [('uni', 'http://www.wikidata.org/entity/Q1632525'), ('name', 'Naples Eastern University')]
# [('uni', 'http://www.wikidata.org/entity/Q645663'), ('name', 'University of Pisa')]
# [('uni', 'http://www.wikidata.org/entity/Q532822'), ('name', 'University of Sassari')]
# [('uni', 'http://www.wikidata.org/entity/Q691851'), ('name', 'University of Naples Federico II')]
# [('uni', 'http://www.wikidata.org/entity/Q2032536'), ('name', 'Pontifical Urbaniana University')]
# [('uni', 'http://www.wikidata.org/entity/Q1248821'), ('name', 'University of Catania')]
# [('uni', 'http://www.wikidata.org/entity/Q1641504'), ('name', 'University of Palermo')]
# [('uni', 'http://www.wikidata.org/entity/Q1758474'), ('name', 'University of Parma')]
# [('uni', 'http://www.wikidata.org/entity/Q1073674'), ('name', 'University of Milan-Bicocca')]
# [('uni', 'http://www.wikidata.org/entity/Q1236136'), ('name', 'University of Bari')]
# [('uni', 'http://www.wikidata.org/entity/Q676817'), ('name', 'University of Camerino')]
# [('uni', 'http://www.wikidata.org/entity/Q3551506'), ('name', 'Vita-Salute San Raffaele University')]
# [('uni', 'http://www.wikidata.org/entity/Q3803694'), ('name', 'Scuola Superiore Studi Pavia IUSS')]
# [('uni', 'http://www.wikidata.org/entity/Q6232900'), ('name', 'John Felice Rome Center')]
# [('uni', 'http://www.wikidata.org/entity/Q2523033'), ('name', 'University of Gastronomic Sciences')]
# [('uni', 'http://www.wikidata.org/entity/Q3551385'), ('name', 'University Carlo Cattaneo')]
# [('uni', 'http://www.wikidata.org/entity/Q1168859'), ('name', 'Accademia Albertina')]
# [('uni', 'http://www.wikidata.org/entity/Q2261128'), ('name', "D'Annunzio University of Chieti–Pescara")]
# [('uni', 'http://www.wikidata.org/entity/Q1084409'), ('name', 'Marche Polytechnic University')]
# [('uni', 'http://www.wikidata.org/entity/Q2531629'), ('name', 'University of Verona')]
# [('uni', 'http://www.wikidata.org/entity/Q64153182'), ('name', 'Monash University Prato')]
# [('uni', 'http://www.wikidata.org/entity/Q4654029'), ('name', 'ASAG – Postgraduate School of Psychology Agostino Gemelli')]
# [('uni', 'http://www.wikidata.org/entity/Q4671475'), ('name', 'Academy of Fine Arts, Verona')]
# [('uni', 'http://www.wikidata.org/entity/Q2424299'), ('name', 'International School for Advanced Studies')]
# [('uni', 'http://www.wikidata.org/entity/Q1235561'), ('name', 'University of Eastern Piedmont')]
# [('uni', 'http://www.wikidata.org/entity/Q338481'), ('name', 'Academy of Fine Arts')]
# [('uni', 'http://www.wikidata.org/entity/Q1378099'), ('name', 'European University Institute')]
# [('uni', 'http://www.wikidata.org/entity/Q6039434'), ('name', 'Institute for International Political Studies')]
# [('uni', 'http://www.wikidata.org/entity/Q1934874'), ('name', 'Military Academy of Modena')]
# [('uni', 'http://www.wikidata.org/entity/Q35326177'), ('name', 'Facoltà di Architettura di Torino')]
# [('uni', 'http://www.wikidata.org/entity/Q35326590'), ('name', 'Palazzo Nuovo')]
# [('uni', 'http://www.wikidata.org/entity/Q266537'), ('name', 'Magna Græcia University')]
# [('uni', 'http://www.wikidata.org/entity/Q617446'), ('name', 'University of Foggia')]
# [('uni', 'http://www.wikidata.org/entity/Q469446'), ('name', 'American University of Rome')]
# [('uni', 'http://www.wikidata.org/entity/Q1309998'), ('name', 'University of Insubria')]
# [('uni', 'http://www.wikidata.org/entity/Q1230902'), ('name', 'University of Salento')]
# [('uni', 'http://www.wikidata.org/entity/Q1494671'), ('name', "University of L'Aquila")]
# [('uni', 'http://www.wikidata.org/entity/Q1780716'), ('name', 'Mediterranea University of Reggio Calabria')]
# [('uni', 'http://www.wikidata.org/entity/Q59386762'), ('name', 'Humanitas University')]
# [('uni', 'http://www.wikidata.org/entity/Q39918611'), ('name', 'Universita degli Studi Di Cagliari Cittadella Universitaria')]
# [('uni', 'http://www.wikidata.org/entity/Q3682946'), ('name', 'Collegio Carlo Alberto')]
# [('uni', 'http://www.wikidata.org/entity/Q1274578'), ('name', 'Università europea di Roma')]
# [('uni', 'http://www.wikidata.org/entity/Q2319621'), ('name', "Università della Valle d'Aosta")]
# [('uni', 'http://www.wikidata.org/entity/Q3551650'), ('name', 'Parthenope University of Naples')]
# [('uni', 'http://www.wikidata.org/entity/Q1093340'), ('name', 'University of Molise')]
# [('uni', 'http://www.wikidata.org/entity/Q4005942'), ('name', 'Università degli Studi di Roma "Unitelma Sapienza"')]
# [('uni', 'http://www.wikidata.org/entity/Q2120406'), ('name', 'Pontifical Institute of Christian Archaeology')]
# [('uni', 'http://www.wikidata.org/entity/Q1481995'), ('name', 'Kore University of Enna')]
# [('uni', 'http://www.wikidata.org/entity/Q3551769'), ('name', 'University of Sannio')]
# [('uni', 'http://www.wikidata.org/entity/Q3152661'), ('name', 'Foro Italico University of Rome')]
# [('uni', 'http://www.wikidata.org/entity/Q504263'), ('name', 'University of Cassino')]
# [('uni', 'http://www.wikidata.org/entity/Q3833046'), ('name', 'Link Campus University')]
# [('uni', 'http://www.wikidata.org/entity/Q3551499'), ('name', 'Suor Orsola Benincasa University of Naples')]
# [('uni', 'http://www.wikidata.org/entity/Q1314405'), ('name', 'John Cabot University')]
# [('uni', 'http://www.wikidata.org/entity/Q29915035'), ('name', 'Free Academy of Fine Arts (LABA)')]
# [('uni', 'http://www.wikidata.org/entity/Q107496653'), ('name', 'Polo Universitario Grossetano')]
# [('uni', 'http://www.wikidata.org/entity/Q3943517'), ('name', 'SDA Bocconi School of Management')]
# [('uni', 'http://www.wikidata.org/entity/Q3604024'), ('name', 'Accademia di Belle Arti di Perugia')]
# [('uni', 'http://www.wikidata.org/entity/Q5458567'), ('name', 'Fleming College Florence')]
# [('uni', 'http://www.wikidata.org/entity/Q3831607'), ('name', 'Libera Università Mediterranea')]
# [('uni', 'http://www.wikidata.org/entity/Q1127590'), ('name', 'Consorzio ICoN')]
# [('uni', 'http://www.wikidata.org/entity/Q7743414'), ('name', 'The Johns Hopkins University SAIS Bologna Center')]
# [('uni', 'http://www.wikidata.org/entity/Q4652396'), ('name', 'ALMED – Postgraduate School of Media Communications and Performing Arts')]
# [('uni', 'http://www.wikidata.org/entity/Q4005949'), ('name', 'Università telematica internazionale UniNettuno')]
# [('uni', 'http://www.wikidata.org/entity/Q2905216'), ('name', 'Venice International University')]
# [('uni', 'http://www.wikidata.org/entity/Q3996914'), ('name', 'Touro University Rome')]
# [('uni', 'http://www.wikidata.org/entity/Q1054341'), ('name', 'Centre for Studies on Federalism')]
# [('uni', 'http://www.wikidata.org/entity/Q15261139'), ('name', 'National Observatory of Outsider Art')]
# [('uni', 'http://www.wikidata.org/entity/Q84035409'), ('name', 'Università dei cani da tartufo')]
# [('uni', 'http://www.wikidata.org/entity/Q16949007'), ('name', "Lorenzo de' Medici School")]
# [('uni', 'http://www.wikidata.org/entity/Q14539971'), ('name', 'Accademia italiana')]
# [('uni', 'http://www.wikidata.org/entity/Q4652448'), ('name', 'ALTIS – Postgraduate School Business & Society')]
# [('uni', 'http://www.wikidata.org/entity/Q4654207'), ('name', 'ASERI – Postgraduate School of Economics and International Relations')]
# [('uni', 'http://www.wikidata.org/entity/Q45745121'), ('name', 'Istituto di Moda Burgo')]
# [('uni', 'http://www.wikidata.org/entity/Q3604040'), ('name', 'Accademia di belle arti europea dei media')]
# [('uni', 'http://www.wikidata.org/entity/Q29366803'), ('name', 'Rome Business School, Rome')]
# [('uni', 'http://www.wikidata.org/entity/Q3270465'), ('name', 'University of Vicenza')]
# [('uni', 'http://www.wikidata.org/entity/Q4005936'), ('name', 'University for Foreigners "Dante Alighieri" of Reggio Calabria')]
# [('uni', 'http://www.wikidata.org/entity/Q7896507'), ('name', 'University of Turin, Faculty of Law')]
# [('uni', 'http://www.wikidata.org/entity/Q7439503'), ('name', 'Scuola Italiana Design')]
# [('uni', 'http://www.wikidata.org/entity/Q104628992'), ('name', 'Istituto Superiore per Imprenditori e Dirigenti di Azienda')]
# [('uni', 'http://www.wikidata.org/entity/Q3738249'), ('name', 'Theological University of Northern Italy – Turin Campus')]
# [('uni', 'http://www.wikidata.org/entity/Q56254848'), ('name', 'Palazzo Venier delle Torreselle')]
# [('uni', 'http://www.wikidata.org/entity/Q35326042'), ('name', 'Antiche Vetrerie')]
# [('uni', 'http://www.wikidata.org/entity/Q27926167'), ('name', 'Centre for Child Protection')]
# [('uni', 'http://www.wikidata.org/entity/Q7825120'), ('name', 'Toppo Wassermann College')]
# [('uni', 'http://www.wikidata.org/entity/Q7854950'), ('name', 'Turin School of Development')]
# [('uni', 'http://www.wikidata.org/entity/Q3699300'), ('name', 'University of Ragusa')]
# [('uni', 'http://www.wikidata.org/entity/Q107429566'), ('name', 'ICA Istituto Contemporaneo per le Arti')]
# [('uni', 'http://www.wikidata.org/entity/Q3747151'), ('name', 'CUOA Foundation')]
# [('uni', 'http://www.wikidata.org/entity/Q5774694'), ('name', 'History Curriculum at the Gregorian University')]
# [('uni', 'http://www.wikidata.org/entity/Q4654068'), ('name', 'ASA – Postgraduate School of Environmental Studies')]
# [('uni', 'http://www.wikidata.org/entity/Q7391137'), ('name', 'SMEA – Postgraduate School of Agricultural and Food Economics')]
# [('uni', 'http://www.wikidata.org/entity/Q939801'), ('name', 'Università degli Studi Internazionali di Roma – UNINT')]
# [('uni', 'http://www.wikidata.org/entity/Q959524'), ('name', 'Bocconi University')]
# [('uni', 'http://www.wikidata.org/entity/Q1077639'), ('name', 'IULM University of Milan')]
# [('uni', 'http://www.wikidata.org/entity/Q1122851'), ('name', 'Libera Università Internazionale degli Studi Sociali Guido Carli')]
# [('uni', 'http://www.wikidata.org/entity/Q1454044'), ('name', 'Libera Università Maria SS. Assunta')]
# [('uni', 'http://www.wikidata.org/entity/Q4005946'), ('name', 'Università Leonardo da Vinci')]
# [('uni', 'http://www.wikidata.org/entity/Q3682991'), ('name', 'Collegio Superiore di Bologna')]
# [('uni', 'http://www.wikidata.org/entity/Q3953349'), ('name', 'Scuola Politecnica di Design')]
# [('uni', 'http://www.wikidata.org/entity/Q3967519'), ('name', 'St. John International University')]
# [('uni', 'http://www.wikidata.org/entity/Q6092782'), ('name', 'Italian Institute of Human Sciences')]
# [('uni', 'http://www.wikidata.org/entity/Q6505336'), ('name', 'Lay Centre at Foyer Unitas')]
# [('uni', 'http://www.wikidata.org/entity/Q4652446'), ('name', 'ALTEMS – Postgraduate School of Health Economics and Management')]
# [('uni', 'http://www.wikidata.org/entity/Q16967405'), ('name', 'Pontifical universities in Rome')]
# [('uni', 'http://www.wikidata.org/entity/Q35326338'), ('name', 'Ingegneria Mesiano')]
# [('uni', 'http://www.wikidata.org/entity/Q35326604'), ('name', 'Palazzo Venturi')]
# [('uni', 'http://www.wikidata.org/entity/Q35326663'), ('name', 'School of Mathematics, Physics e Natural Sciences')]
# [('uni', 'http://www.wikidata.org/entity/Q209344'), ('name', 'Sapienza University of Rome')]
# [('uni', 'http://www.wikidata.org/entity/Q1751060'), ('name', 'University of Trieste')]
# [('uni', 'http://www.wikidata.org/entity/Q1633215'), ('name', 'University of Salerno')]
# [('uni', 'http://www.wikidata.org/entity/Q3953222'), ('name', 'National Film School')]
# [('uni', 'http://www.wikidata.org/entity/Q131262'), ('name', 'University of Bologna')]
# [('uni', 'http://www.wikidata.org/entity/Q26319'), ('name', 'Università degli Studi Niccolò Cusano')]
# [('uni', 'http://www.wikidata.org/entity/Q951184'), ('name', 'Pontifical Biblical Institute')]
# [('uni', 'http://www.wikidata.org/entity/Q2303527'), ('name', 'University of Teramo')]
# [('uni', 'http://www.wikidata.org/entity/Q45855'), ('name', 'University of Bergamo')]
# [('uni', 'http://www.wikidata.org/entity/Q9364612'), ('name', 'St. Clement Ukrainian Catholic University in Rome')]
# [('uni', 'http://www.wikidata.org/entity/Q15102345'), ('name', 'Pápai Magyar Intézet')]
# [('uni', 'http://www.wikidata.org/entity/Q4005892'), ('name', 'Università degli Studi eCampus')]
# [('uni', 'http://www.wikidata.org/entity/Q1084383'), ('name', 'University of Basilicata')]
# [('uni', 'http://www.wikidata.org/entity/Q4005890'), ('name', "Università degli Studi ''Guglielmo Marconi''")]
# [('uni', 'http://www.wikidata.org/entity/Q850927'), ('name', 'Mediterranean Universities Union')]
# [('uni', 'http://www.wikidata.org/entity/Q4005887'), ('name', 'Università "Universitas Mercatorum"')]
# [('uni', 'http://www.wikidata.org/entity/Q16566666'), ('name', 'ISIA Urbino')]
# [('uni', 'http://www.wikidata.org/entity/Q50379462'), ('name', 'Higher Institute for Artistic Industries Firenze')]
# [('uni', 'http://www.wikidata.org/entity/Q50379463'), ('name', 'Higher Institute for Artistic Industries Roma')]
# [('uni', 'http://www.wikidata.org/entity/Q4005948'), ('name', 'Università telematica San Raffaele')]
# [('uni', 'http://www.wikidata.org/entity/Q4005943'), ('name', 'Università degli Studi Giustino Fortunato')]
# [('uni', 'http://www.wikidata.org/entity/Q4005947'), ('name', 'Università degli Studi Pegaso')]
# [('uni', 'http://www.wikidata.org/entity/Q4005945'), ('name', 'Università Telematica degli Studi IUL')]
# [('uni', 'http://www.wikidata.org/entity/Q3788819'), ('name', 'Higher Institute for Artistic Industries Faenza')]
# 182

# %%
# Get all cities in which there is at least university in Italy
queryString = """
SELECT DISTINCT ?city ?name
WHERE {
    # ?uni wdt:P17 wd:Q38.             #BGP for country 'Italy'
    # ?uni wdt:P31/wdt:P279* wd:Q3918. #BGP for instance of university or a subclass
    # ?uni wdt:P131 ?city.             #BGP to retieve the city 
   
    # ?city sc:name ?name.
}
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('city', 'http://www.wikidata.org/entity/Q13619'), ('name', 'Cosenza')]
# [('city', 'http://www.wikidata.org/entity/Q6526'), ('name', 'Bolzano')]
# [('city', 'http://www.wikidata.org/entity/Q13395'), ('name', 'Viterbo')]
# [('city', 'http://www.wikidata.org/entity/Q2759'), ('name', 'Urbino')]
# [('city', 'http://www.wikidata.org/entity/Q13666'), ('name', 'Messina')]
# [('city', 'http://www.wikidata.org/entity/Q2044'), ('name', 'Florence')]
# [('city', 'http://www.wikidata.org/entity/Q220'), ('name', 'Rome')]
# [('city', 'http://www.wikidata.org/entity/Q2751'), ('name', 'Siena')]
# [('city', 'http://www.wikidata.org/entity/Q3437'), ('name', 'Perugia')]
# [('city', 'http://www.wikidata.org/entity/Q3519'), ('name', 'Bari')]
# [('city', 'http://www.wikidata.org/entity/Q490'), ('name', 'Milan')]
# [('city', 'http://www.wikidata.org/entity/Q495'), ('name', 'Turin')]
# [('city', 'http://www.wikidata.org/entity/Q6259'), ('name', 'Pavia')]
# [('city', 'http://www.wikidata.org/entity/Q641'), ('name', 'Venice')]
# [('city', 'http://www.wikidata.org/entity/Q13135'), ('name', 'Macerata')]
# [('city', 'http://www.wikidata.org/entity/Q1906'), ('name', 'Caserta')]
# [('city', 'http://www.wikidata.org/entity/Q2790'), ('name', 'Udine')]
# [('city', 'http://www.wikidata.org/entity/Q6221'), ('name', 'Brescia')]
# [('city', 'http://www.wikidata.org/entity/Q279'), ('name', 'Modena')]
# [('city', 'http://www.wikidata.org/entity/Q3376'), ('name', 'Trento')]
# [('city', 'http://www.wikidata.org/entity/Q53946'), ('name', 'Rende')]
# [('city', 'http://www.wikidata.org/entity/Q1897'), ('name', 'Cagliari')]
# [('city', 'http://www.wikidata.org/entity/Q1449'), ('name', 'Genoa')]
# [('city', 'http://www.wikidata.org/entity/Q73489'), ('name', 'Camerino')]
# [('city', 'http://www.wikidata.org/entity/Q13362'), ('name', 'Ferrara')]
# [('city', 'http://www.wikidata.org/entity/Q13375'), ('name', 'Pisa')]
# [('city', 'http://www.wikidata.org/entity/Q13629'), ('name', 'Sassari')]
# [('city', 'http://www.wikidata.org/entity/Q2634'), ('name', 'Naples')]
# [('city', 'http://www.wikidata.org/entity/Q2656'), ('name', 'Palermo')]
# [('city', 'http://www.wikidata.org/entity/Q2683'), ('name', 'Parma')]
# [('city', 'http://www.wikidata.org/entity/Q1903'), ('name', 'Catania')]
# [('city', 'http://www.wikidata.org/entity/Q617'), ('name', 'Padua')]
# [('city', 'http://www.wikidata.org/entity/Q3883'), ('name', 'Catanzaro')]
# [('city', 'http://www.wikidata.org/entity/Q2028'), ('name', 'Verona')]
# [('city', 'http://www.wikidata.org/entity/Q6046'), ('name', 'Novara')]
# [('city', 'http://www.wikidata.org/entity/Q82670'), ('name', 'Fiesole')]
# [('city', 'http://www.wikidata.org/entity/Q147015'), ('name', 'Castellanza')]
# [('city', 'http://www.wikidata.org/entity/Q3415'), ('name', 'Ancona')]
# [('city', 'http://www.wikidata.org/entity/Q546'), ('name', 'Trieste')]
# [('city', 'http://www.wikidata.org/entity/Q5990'), ('name', 'Vercelli')]
# [('city', 'http://www.wikidata.org/entity/Q6088'), ('name', 'Alessandria')]
# [('city', 'http://www.wikidata.org/entity/Q6285'), ('name', 'Varese')]
# [('city', 'http://www.wikidata.org/entity/Q13377'), ('name', 'Prato')]
# [('city', 'http://www.wikidata.org/entity/Q13464'), ('name', 'Foggia')]
# [('city', 'http://www.wikidata.org/entity/Q13138'), ('name', 'Chieti')]
# [('city', 'http://www.wikidata.org/entity/Q264149'), ('name', 'Pollenzo')]
# [('city', 'http://www.wikidata.org/entity/Q116592'), ('name', 'Cassino')]
# [('city', 'http://www.wikidata.org/entity/Q13386'), ('name', 'Lecce')]
# [('city', 'http://www.wikidata.org/entity/Q3497'), ('name', 'Campobasso')]
# [('city', 'http://www.wikidata.org/entity/Q13437'), ('name', 'Benevento')]
# [('city', 'http://www.wikidata.org/entity/Q3476'), ('name', 'L’Aquila')]
# [('city', 'http://www.wikidata.org/entity/Q13680'), ('name', 'Caltanissetta')]
# [('city', 'http://www.wikidata.org/entity/Q13687'), ('name', 'Enna')]
# [('city', 'http://www.wikidata.org/entity/Q8471'), ('name', 'Reggio Calabria')]
# [('city', 'http://www.wikidata.org/entity/Q42794'), ('name', 'Rozzano')]
# [('city', 'http://www.wikidata.org/entity/Q3367'), ('name', 'Aosta')]
# [('city', 'http://www.wikidata.org/entity/Q284342'), ('name', 'Monserrato')]
# [('city', 'http://www.wikidata.org/entity/Q1891'), ('name', 'Bologna')]
# [('city', 'http://www.wikidata.org/entity/Q6716'), ('name', 'Grosseto')]
# [('city', 'http://www.wikidata.org/entity/Q51819'), ('name', 'Casamassima')]
# [('city', 'http://www.wikidata.org/entity/Q6537'), ('name', 'Vicenza')]
# [('city', 'http://www.wikidata.org/entity/Q13625'), ('name', 'Vibo Valentia')]
# [('city', 'http://www.wikidata.org/entity/Q20425'), ('name', 'Roddi')]
# [('city', 'http://www.wikidata.org/entity/Q140255'), ('name', 'Zagarolo')]
# [('city', 'http://www.wikidata.org/entity/Q13674'), ('name', 'Ragusa')]
# [('city', 'http://www.wikidata.org/entity/Q6231'), ('name', 'Cremona')]
# [('city', 'http://www.wikidata.org/entity/Q46867'), ('name', 'Altavilla Vicentina')]
# [('city', 'http://www.wikidata.org/entity/Q10361'), ('name', 'Vinovo')]
# [('city', 'http://www.wikidata.org/entity/Q51305'), ('name', 'Torrevecchia Teatina')]
# [('city', 'http://www.wikidata.org/entity/Q47638'), ('name', 'Novedrate')]
# [('city', 'http://www.wikidata.org/entity/Q52981'), ('name', 'Faenza')]
# [('city', 'http://www.wikidata.org/entity/Q1083'), ('name', 'Salerno')]
# [('city', 'http://www.wikidata.org/entity/Q3543'), ('name', 'Potenza')]
# [('city', 'http://www.wikidata.org/entity/Q6761'), ('name', 'Livorno')]
# [('city', 'http://www.wikidata.org/entity/Q13137'), ('name', 'Teramo')]
# [('city', 'http://www.wikidata.org/entity/Q628'), ('name', 'Bergamo')]
# 76

# %%
# Get all subjects that have 'poet' as 'occupation' and 'Italians' as 'ethnic group' and their date of birth
# Get informations about the city in which they conduct their university studies
queryString = """
SELECT DISTINCT ?uni ?name
WHERE {
   # ?poet wdt:P106 wd:Q49757 .        #BGP for poet
   # ?poet wdt:P172 wd:Q50001 .        #BGP for 'Italians'
   # ?poet wdt:P69 ?uni .              #BGP for educated at
   # ?uni wdt:P31/wdt:P279* wd:Q3918.  #BGP for universities
   
   # ?uni sc:name ?name.
}
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('uni', 'http://www.wikidata.org/entity/Q209344'), ('name', 'Sapienza University of Rome')]
# [('uni', 'http://www.wikidata.org/entity/Q1243705'), ('name', 'University of Modena and Reggio Emilia')]
# [('uni', 'http://www.wikidata.org/entity/Q219317'), ('name', 'University of Pavia')]
# [('uni', 'http://www.wikidata.org/entity/Q131262'), ('name', 'University of Bologna')]
# [('uni', 'http://www.wikidata.org/entity/Q152171'), ('name', 'University of Bonn')]
# [('uni', 'http://www.wikidata.org/entity/Q193510'), ('name', 'University of Padua')]
# [('uni', 'http://www.wikidata.org/entity/Q209842'), ('name', 'University of Paris')]
# [('uni', 'http://www.wikidata.org/entity/Q820887'), ('name', 'University of Florence')]
# [('uni', 'http://www.wikidata.org/entity/Q955609'), ('name', 'University of Ferrara')]
# [('uni', 'http://www.wikidata.org/entity/Q593321'), ('name', 'University of Genoa')]
# [('uni', 'http://www.wikidata.org/entity/Q645663'), ('name', 'University of Pisa')]
# [('uni', 'http://www.wikidata.org/entity/Q776223'), ('name', 'University of Montpellier')]
# 12

# %%
# Get all subjects that have 'poet' as 'occupation' and 'Italians' as 'ethnic group' and their date of birth
# Get informations about the city in which they conduct their university studies
queryString = """
SELECT DISTINCT ?uni ?name
WHERE {
   # ?poet wdt:P106 wd:Q49757 .        #BGP for poet
   # ?poet wdt:P172 wd:Q50001 .        #BGP for 'Italians'
   # ?poet wdt:P69 ?uni .              #BGP for educated at
   # ?uni wdt:P31/wdt:P279* wd:Q3918.  #BGP for universities
   # ?uni wdt:P17 wd:Q38.              #BGP for country 'Italy'
   # ?uni sc:name ?name.
}
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('uni', 'http://www.wikidata.org/entity/Q209344'), ('name', 'Sapienza University of Rome')]
# [('uni', 'http://www.wikidata.org/entity/Q1243705'), ('name', 'University of Modena and Reggio Emilia')]
# [('uni', 'http://www.wikidata.org/entity/Q219317'), ('name', 'University of Pavia')]
# [('uni', 'http://www.wikidata.org/entity/Q131262'), ('name', 'University of Bologna')]
# [('uni', 'http://www.wikidata.org/entity/Q193510'), ('name', 'University of Padua')]
# [('uni', 'http://www.wikidata.org/entity/Q820887'), ('name', 'University of Florence')]
# [('uni', 'http://www.wikidata.org/entity/Q955609'), ('name', 'University of Ferrara')]
# [('uni', 'http://www.wikidata.org/entity/Q593321'), ('name', 'University of Genoa')]
# [('uni', 'http://www.wikidata.org/entity/Q645663'), ('name', 'University of Pisa')]
# 9

# %%
# Get all subjects that have 'poet' as 'occupation' and 'Italians' as 'ethnic group' and their date of birth
# Get informations about the city in which they conduct their university studies
queryString = """
SELECT DISTINCT ?uni ?name
WHERE {
   # ?poet wdt:P106 wd:Q49757 .        #BGP for poet
   # ?poet wdt:P172 wd:Q50001 .        #BGP for 'Italians'
   # ?poet wdt:P69 ?uni .              #BGP for educated at
   # ?uni wdt:P31/wdt:P279* wd:Q3918.  #BGP for universities
   # ?uni wdt:P17 wd:Q38.              #BGP for country 'Italy'
   # ?uni wdt:P131 ?city.              #BGP to retieve the city 
   # ?city sc:name ?name.
}
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('uni', 'http://www.wikidata.org/entity/Q593321'), ('name', 'Genoa')]
# [('uni', 'http://www.wikidata.org/entity/Q955609'), ('name', 'Ferrara')]
# [('uni', 'http://www.wikidata.org/entity/Q645663'), ('name', 'Pisa')]
# [('uni', 'http://www.wikidata.org/entity/Q131262'), ('name', 'Bologna')]
# [('uni', 'http://www.wikidata.org/entity/Q820887'), ('name', 'Florence')]
# [('uni', 'http://www.wikidata.org/entity/Q209344'), ('name', 'Rome')]
# [('uni', 'http://www.wikidata.org/entity/Q219317'), ('name', 'Pavia')]
# [('uni', 'http://www.wikidata.org/entity/Q1243705'), ('name', 'Modena')]
# [('uni', 'http://www.wikidata.org/entity/Q193510'), ('name', 'Padua')]
# 9

# %%
# Get all the cities in which italian poets were born or attended university
queryString = """
SELECT DISTINCT ?city ?cityName
WHERE {

    {
        # Get all the cities in which Italian poets were born
        SELECT ?city ?cityName
        WHERE {
           # ?poet wdt:P106 wd:Q49757 .
           # ?poet wdt:P172 wd:Q50001 .
           # ?poet wdt:P19 ?city .
           # ?city sc:name ?cityName.
        }
    } UNION {
        # Get all the cities in which Italian poets attended university
        SELECT ?city ?cityName
        WHERE {
           # ?poet wdt:P106 wd:Q49757 .        #BGP for poet
           # ?poet wdt:P172 wd:Q50001 .        #BGP for 'Italians'
           # ?poet wdt:P69 ?uni .              #BGP for educated at
           # ?uni wdt:P31/wdt:P279* wd:Q3918.  #BGP for universities
           # ?uni wdt:P17 wd:Q38.              #BGP for country 'Italy'
           # ?uni wdt:P131 ?city.              #BGP to retieve the city 
           # ?city sc:name ?cityName.
        }
    }

}

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('city', 'http://www.wikidata.org/entity/Q13378'), ('cityName', 'Arezzo')]
# [('city', 'http://www.wikidata.org/entity/Q1449'), ('cityName', 'Genoa')]
# [('city', 'http://www.wikidata.org/entity/Q1722'), ('cityName', 'Dubrovnik')]
# [('city', 'http://www.wikidata.org/entity/Q219330'), ('cityName', 'Pietrasanta')]
# [('city', 'http://www.wikidata.org/entity/Q52069'), ('cityName', 'Caprese Michelangelo')]
# [('city', 'http://www.wikidata.org/entity/Q1335'), ('cityName', 'Montevideo')]
# [('city', 'http://www.wikidata.org/entity/Q13362'), ('cityName', 'Ferrara')]
# [('city', 'http://www.wikidata.org/entity/Q144880'), ('cityName', 'Zakynthos')]
# [('city', 'http://www.wikidata.org/entity/Q2044'), ('cityName', 'Florence')]
# [('city', 'http://www.wikidata.org/entity/Q220'), ('cityName', 'Rome')]
# [('city', 'http://www.wikidata.org/entity/Q2634'), ('cityName', 'Naples')]
# [('city', 'http://www.wikidata.org/entity/Q2683'), ('cityName', 'Parma')]
# [('city', 'http://www.wikidata.org/entity/Q490'), ('cityName', 'Milan')]
# [('city', 'http://www.wikidata.org/entity/Q6247'), ('cityName', 'Mantua')]
# [('city', 'http://www.wikidata.org/entity/Q641'), ('cityName', 'Venice')]
# [('city', 'http://www.wikidata.org/entity/Q84'), ('cityName', 'London')]
# [('city', 'http://www.wikidata.org/entity/Q13360'), ('cityName', 'Reggio Emilia')]
# [('city', 'http://www.wikidata.org/entity/Q13678'), ('cityName', 'Agrigento')]
# [('city', 'http://www.wikidata.org/entity/Q20103'), ('cityName', 'Assisi')]
# [('city', 'http://www.wikidata.org/entity/Q20454'), ('cityName', 'Saluzzo')]
# [('city', 'http://www.wikidata.org/entity/Q39790'), ('cityName', 'Sangiano')]
# [('city', 'http://www.wikidata.org/entity/Q6122'), ('cityName', 'Asti')]
# [('city', 'http://www.wikidata.org/entity/Q6231'), ('cityName', 'Cremona')]
# [('city', 'http://www.wikidata.org/entity/Q6244'), ('cityName', 'Lodi')]
# [('city', 'http://www.wikidata.org/entity/Q83362'), ('cityName', 'Recanati')]
# [('city', 'http://www.wikidata.org/entity/Q270613'), ('cityName', 'Celle Ligure')]
# [('city', 'http://www.wikidata.org/entity/Q617'), ('cityName', 'Padua')]
# [('city', 'http://www.wikidata.org/entity/Q87'), ('cityName', 'Alexandria')]
# [('city', 'http://www.wikidata.org/entity/Q102634'), ('cityName', 'Monsummano Terme')]
# [('city', 'http://www.wikidata.org/entity/Q117032'), ('cityName', 'Pico, Lazio')]
# [('city', 'http://www.wikidata.org/entity/Q56687351'), ('cityName', 'Valdicastello Carducci')]
# [('city', 'http://www.wikidata.org/entity/Q13375'), ('cityName', 'Pisa')]
# [('city', 'http://www.wikidata.org/entity/Q1891'), ('cityName', 'Bologna')]
# [('city', 'http://www.wikidata.org/entity/Q6259'), ('cityName', 'Pavia')]
# [('city', 'http://www.wikidata.org/entity/Q279'), ('cityName', 'Modena')]
# 35

# %%
# Given a city retrieve the Italian poets that were born there
queryString = """
SELECT DISTINCT ?poet ?name
WHERE {

    # ?poet wdt:P106 wd:Q49757 . #BGP for poet
    # ?poet wdt:P172 wd:Q50001 . #BGP for 'Italians'
    # ?poet sc:name ?name.

    # ?poet wdt:P19 ?city .
    FILTER(?city = wd:Q220)    #Filter only for city 'Rome'
}

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('poet', 'http://www.wikidata.org/entity/Q29473'), ('name', 'Pietro Metastasio')]
# [('poet', 'http://www.wikidata.org/entity/Q133855'), ('name', 'Guillaume Apollinaire')]
# [('poet', 'http://www.wikidata.org/entity/Q334147'), ('name', 'Julius Evola')]
# 3

# %%
# Given a city retrieve the Italian poets that were born there
queryString = """
SELECT DISTINCT ?poet ?name
WHERE {

    # ?poet wdt:P106 wd:Q49757 . #BGP for poet
    # ?poet wdt:P172 wd:Q50001 . #BGP for 'Italians'
    # ?poet sc:name ?name.

    # ?poet wdt:P19 ?city .
    FILTER(?city = wd:Q2044)    #Filter only for city 'Florence'
}

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('poet', 'http://www.wikidata.org/entity/Q7803'), ('name', 'Bronzino')]
# [('poet', 'http://www.wikidata.org/entity/Q1067'), ('name', 'Dante Alighieri')]
# [('poet', 'http://www.wikidata.org/entity/Q1402'), ('name', 'Giovanni Boccaccio')]
# [('poet', 'http://www.wikidata.org/entity/Q2252971'), ('name', 'Vincenzo da Filicaja')]
# 4

# %%
# Given a city retrieve the number of Italian poets that were born there
queryString = """
SELECT COUNT(DISTINCT (?poet)) as ?born
WHERE {

    # ?poet wdt:P106 wd:Q49757 . #BGP for poet
    # ?poet wdt:P172 wd:Q50001 . #BGP for 'Italians'
    # ?poet sc:name ?name.

    # ?poet wdt:P19 ?city .
    FILTER(?city = wd:Q2044)    #Filter only for city 'Florence'
}

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('born', '4')]
# 1

# %%
# Given a city retrieve the Italian poets that were educated there
queryString = """
SELECT DISTINCT ?poet ?name
WHERE {

    # ?poet wdt:P106 wd:Q49757 .        #BGP for poet
    # ?poet wdt:P172 wd:Q50001 .        #BGP for 'Italians'
    
    # ?poet wdt:P69 ?uni .              #BGP for educated at
    # ?uni wdt:P31/wdt:P279* wd:Q3918.  #BGP for universities
    # ?uni wdt:P17 wd:Q38.              #BGP for country 'Italy'
    # ?uni wdt:P131 ?city.              #BGP to retieve the city 

    # ?poet sc:name ?name.

    FILTER(?city = wd:Q2044)    #Filter only for city 'Florence'
}

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('poet', 'http://www.wikidata.org/entity/Q5592'), ('name', 'Michelangelo')]
# [('poet', 'http://www.wikidata.org/entity/Q560541'), ('name', 'Tommaso Landolfi')]
# 2

# %%
# Given a city retrieve the number Italian poets that were educated there
queryString = """
SELECT COUNT(DISTINCT (?poet)) as ?educated
WHERE {

    # ?poet wdt:P106 wd:Q49757 .        #BGP for poet
    # ?poet wdt:P172 wd:Q50001 .        #BGP for 'Italians'
    
    # ?poet wdt:P69 ?uni .              #BGP for educated at
    # ?uni wdt:P31/wdt:P279* wd:Q3918.  #BGP for universities
    # ?uni wdt:P17 wd:Q38.              #BGP for country 'Italy'
    # ?uni wdt:P131 ?city.              #BGP to retieve the city 

    # ?poet sc:name ?name.

    FILTER(?city = wd:Q2044)    #Filter only for city 'Florence'
}

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('educated', '2')]
# 1

# %%
# Given a city retrieve the Italian poets that were born or educated there
queryString = """
SELECT ?city ?born ?educated
WHERE {

    {
        SELECT ?city COUNT(DISTINCT (?poet)) as ?born
        WHERE {
            # ?poet wdt:P106 wd:Q49757 . #BGP for poet
            # ?poet wdt:P172 wd:Q50001 . #BGP for 'Italians'
            # ?poet sc:name ?name.

            # ?poet wdt:P19 ?city .
        }
    }
    UNION 
    {
        SELECT ?city COUNT(DISTINCT (?poet)) as ?educated
        WHERE {
            # ?poet wdt:P106 wd:Q49757 .        #BGP for poet
            # ?poet wdt:P172 wd:Q50001 .        #BGP for 'Italians'

            # ?poet wdt:P69 ?uni .              #BGP for educated at
            # ?uni wdt:P31/wdt:P279* wd:Q3918.  #BGP for universities
            # ?uni wdt:P17 wd:Q38.              #BGP for country 'Italy'
            # ?uni wdt:P131 ?city.              #BGP to retieve the city 
        }
    }

    FILTER(?city = wd:Q2044)    #Filter only for city 'Florence'
}

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('city', 'http://www.wikidata.org/entity/Q2044'), ('born', '4')]
# [('city', 'http://www.wikidata.org/entity/Q2044'), ('educated', '2')]
# 2

# %%
# Given a city retrieve the Italian poets that were born or educated there (removed BGP to impose that the university is in Italy)
queryString = """
SELECT ?city ?born ?educated
WHERE {

    {
        SELECT ?city COUNT(DISTINCT (?poet)) as ?born
        WHERE {
            # ?poet wdt:P106 wd:Q49757 . #BGP for poet
            # ?poet wdt:P172 wd:Q50001 . #BGP for 'Italians'
            # ?poet sc:name ?name.

            # ?poet wdt:P19 ?city .
        }
    }
    UNION 
    {
        SELECT ?city COUNT(DISTINCT (?poet)) as ?educated
        WHERE {
            # ?poet wdt:P106 wd:Q49757 .        #BGP for poet
            # ?poet wdt:P172 wd:Q50001 .        #BGP for 'Italians'

            # ?poet wdt:P69 ?uni .              #BGP for educated at
            # ?uni wdt:P31/wdt:P279* wd:Q3918.  #BGP for universities
            # ?uni wdt:P131 ?city.              #BGP to retieve the city 
        }
    }

    FILTER(?city = wd:Q2044)    #Filter only for city 'Florence'
}

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('city', 'http://www.wikidata.org/entity/Q2044'), ('born', '4')]
# [('city', 'http://www.wikidata.org/entity/Q2044'), ('educated', '2')]
# 2

# %%
# Given a city retrieve the Italian poets that were born or educated there and sums the two counts
queryString = """
SELECT ?city SUM(?count) as ?count
WHERE {

    {
        #Number of poets born in the city
        SELECT ?city COUNT(DISTINCT (?poet)) as ?count
        WHERE {
            # ?poet wdt:P106 wd:Q49757 . #BGP for poet
            # ?poet wdt:P172 wd:Q50001 . #BGP for 'Italians'
            # ?poet sc:name ?name.

            # ?poet wdt:P19 ?city .
        }
    }
    UNION 
    {
        #Number of poets that studied in the city
        SELECT ?city COUNT(DISTINCT (?poet)) as ?count
        WHERE {
            # ?poet wdt:P106 wd:Q49757 .        #BGP for poet
            # ?poet wdt:P172 wd:Q50001 .        #BGP for 'Italians'

            # ?poet wdt:P69 ?uni .              #BGP for educated at
            # ?uni wdt:P31/wdt:P279* wd:Q3918.  #BGP for universities
            # ?uni wdt:P17 wd:Q38.              #BGP for country 'Italy'
            # ?uni wdt:P131 ?city.              #BGP to retieve the city 
        }
    }

    FILTER(?city = wd:Q2044)    #Filter only for city 'Florence'
}
GROUP BY ?city

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('city', 'http://www.wikidata.org/entity/Q2044'), ('count', '6')]
# 1

# %%
# Given a city retrieve the Italian poets that were born or educated there and sums the two counts (removed BGP to impose that the university is in Italy)
queryString = """
SELECT ?city SUM(?count) as ?count
WHERE {

    {
        #Number of poets born in the city
        SELECT ?city COUNT(DISTINCT (?poet)) as ?count
        WHERE {
            # ?poet wdt:P106 wd:Q49757 . #BGP for poet
            # ?poet wdt:P172 wd:Q50001 . #BGP for 'Italians'
            # ?poet sc:name ?name.

            # ?poet wdt:P19 ?city .
        }
    }
    UNION 
    {
        #Number of poets that studied in the city
        SELECT ?city COUNT(DISTINCT (?poet)) as ?count
        WHERE {
            # ?poet wdt:P106 wd:Q49757 .        #BGP for poet
            # ?poet wdt:P172 wd:Q50001 .        #BGP for 'Italians'

            # ?poet wdt:P69 ?uni .              #BGP for educated at
            # ?uni wdt:P31/wdt:P279* wd:Q3918.  #BGP for universities
            # ?uni wdt:P131 ?city.              #BGP to retieve the city 
        }
    }

    FILTER(?city = wd:Q2044)    #Filter only for city 'Florence'
}
GROUP BY ?city

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('city', 'http://www.wikidata.org/entity/Q2044'), ('count', '6')]
# 1

# %%
# Given a city retrieve the Italian poets were born or educated there and sums the two counts
queryString = """
SELECT ?city ?cityName SUM(?count) as ?count
WHERE {

    {
        #Get all the cities in which Italian potes were born or studied
        SELECT DISTINCT ?city ?cityName
        WHERE {
        
            {
                # Get all the cities in which Italian poets were born
                SELECT ?city ?cityName
                WHERE {
                   # ?poet wdt:P106 wd:Q49757 .
                   # ?poet wdt:P172 wd:Q50001 .
                   # ?poet wdt:P19 ?city .
                   # ?city sc:name ?cityName.
                }
            } UNION {
                # Get all the cities in which Italian poets attended university
                SELECT ?city ?cityName
                WHERE {
                   # ?poet wdt:P106 wd:Q49757 .        #BGP for poet
                   # ?poet wdt:P172 wd:Q50001 .        #BGP for 'Italians'
                   # ?poet wdt:P69 ?uni .              #BGP for educated at
                   # ?uni wdt:P31/wdt:P279* wd:Q3918.  #BGP for universities
                   # ?uni wdt:P17 wd:Q38.              #BGP for country 'Italy'
                   # ?uni wdt:P131 ?city.              #BGP to retieve the city 
                   # ?city sc:name ?cityName.
                }
            }
            
        }
    }

    {
        #Number of poets born in the city
        SELECT ?city COUNT(DISTINCT (?poet)) as ?count
        WHERE {
            # ?poet wdt:P106 wd:Q49757 . #BGP for poet
            # ?poet wdt:P172 wd:Q50001 . #BGP for 'Italians'
            # ?poet sc:name ?name.

            # ?poet wdt:P19 ?city .
        }
    }
    UNION 
    {
        #Number of poets that studied in the city
        SELECT ?city COUNT(DISTINCT (?poet)) as ?count
        WHERE {
            # ?poet wdt:P106 wd:Q49757 .        #BGP for poet
            # ?poet wdt:P172 wd:Q50001 .        #BGP for 'Italians'

            # ?poet wdt:P69 ?uni .              #BGP for educated at
            # ?uni wdt:P31/wdt:P279* wd:Q3918.  #BGP for universities
            # ?uni wdt:P17 wd:Q38.              #BGP for country 'Italy'
            # ?uni wdt:P131 ?city.              #BGP to retieve the city 
        }
    }

}
GROUP BY ?city ?cityName

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('city', 'http://www.wikidata.org/entity/Q2634'), ('cityName', 'Naples'), ('count', '1')]
# [('city', 'http://www.wikidata.org/entity/Q220'), ('cityName', 'Rome'), ('count', '5')]
# [('city', 'http://www.wikidata.org/entity/Q1449'), ('cityName', 'Genoa'), ('count', '4')]
# [('city', 'http://www.wikidata.org/entity/Q219330'), ('cityName', 'Pietrasanta'), ('count', '1')]
# [('city', 'http://www.wikidata.org/entity/Q279'), ('cityName', 'Modena'), ('count', '1')]
# [('city', 'http://www.wikidata.org/entity/Q52069'), ('cityName', 'Caprese Michelangelo'), ('count', '1')]
# [('city', 'http://www.wikidata.org/entity/Q83362'), ('cityName', 'Recanati'), ('count', '1')]
# [('city', 'http://www.wikidata.org/entity/Q270613'), ('cityName', 'Celle Ligure'), ('count', '1')]
# [('city', 'http://www.wikidata.org/entity/Q6247'), ('cityName', 'Mantua'), ('count', '1')]
# [('city', 'http://www.wikidata.org/entity/Q20103'), ('cityName', 'Assisi'), ('count', '1')]
# [('city', 'http://www.wikidata.org/entity/Q13375'), ('cityName', 'Pisa'), ('count', '1')]
# [('city', 'http://www.wikidata.org/entity/Q2044'), ('cityName', 'Florence'), ('count', '6')]
# [('city', 'http://www.wikidata.org/entity/Q13378'), ('cityName', 'Arezzo'), ('count', '2')]
# [('city', 'http://www.wikidata.org/entity/Q117032'), ('cityName', 'Pico, Lazio'), ('count', '1')]
# [('city', 'http://www.wikidata.org/entity/Q102634'), ('cityName', 'Monsummano Terme'), ('count', '1')]
# [('city', 'http://www.wikidata.org/entity/Q1335'), ('cityName', 'Montevideo'), ('count', '1')]
# [('city', 'http://www.wikidata.org/entity/Q490'), ('cityName', 'Milan'), ('count', '1')]
# [('city', 'http://www.wikidata.org/entity/Q6259'), ('cityName', 'Pavia'), ('count', '1')]
# [('city', 'http://www.wikidata.org/entity/Q617'), ('cityName', 'Padua'), ('count', '5')]
# [('city', 'http://www.wikidata.org/entity/Q56687351'), ('cityName', 'Valdicastello Carducci'), ('count', '1')]
# [('city', 'http://www.wikidata.org/entity/Q87'), ('cityName', 'Alexandria'), ('count', '2')]
# [('city', 'http://www.wikidata.org/entity/Q39790'), ('cityName', 'Sangiano'), ('count', '1')]
# [('city', 'http://www.wikidata.org/entity/Q6231'), ('cityName', 'Cremona'), ('count', '1')]
# [('city', 'http://www.wikidata.org/entity/Q13362'), ('cityName', 'Ferrara'), ('count', '2')]
# [('city', 'http://www.wikidata.org/entity/Q1722'), ('cityName', 'Dubrovnik'), ('count', '1')]
# [('city', 'http://www.wikidata.org/entity/Q641'), ('cityName', 'Venice'), ('count', '2')]
# [('city', 'http://www.wikidata.org/entity/Q13360'), ('cityName', 'Reggio Emilia'), ('count', '2')]
# [('city', 'http://www.wikidata.org/entity/Q144880'), ('cityName', 'Zakynthos'), ('count', '1')]
# [('city', 'http://www.wikidata.org/entity/Q20454'), ('cityName', 'Saluzzo'), ('count', '1')]
# [('city', 'http://www.wikidata.org/entity/Q13678'), ('cityName', 'Agrigento'), ('count', '1')]
# [('city', 'http://www.wikidata.org/entity/Q6122'), ('cityName', 'Asti'), ('count', '1')]
# [('city', 'http://www.wikidata.org/entity/Q84'), ('cityName', 'London'), ('count', '1')]
# [('city', 'http://www.wikidata.org/entity/Q6244'), ('cityName', 'Lodi'), ('count', '1')]
# [('city', 'http://www.wikidata.org/entity/Q2683'), ('cityName', 'Parma'), ('count', '1')]
# [('city', 'http://www.wikidata.org/entity/Q1891'), ('cityName', 'Bologna'), ('count', '3')]
# 35

# %%
# Get all the poets that were born and attended university in the same city
queryString = """
SELECT ?pob ?cityName ?poet
WHERE {

       # ?poet wdt:P106 wd:Q49757 .  # BGP for poet
       # ?poet wdt:P172 wd:Q50001 .  # BGP for Italians
       # ?poet wdt:P19 ?pob .        # BGP for place of birth
       
       # ?poet wdt:P69 ?uni .              #BGP for educated at
       # ?uni wdt:P31/wdt:P279* wd:Q3918.  #BGP for universities
       # ?uni wdt:P131 ?uniCity.           #BGP to retieve the city 
       
       FILTER(?pob = ?uniCity)
       
       # ?pob sc:name ?cityName.

}
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('pob', 'http://www.wikidata.org/entity/Q1449'), ('cityName', 'Genoa'), ('poet', 'http://www.wikidata.org/entity/Q350103')]
# [('pob', 'http://www.wikidata.org/entity/Q1449'), ('cityName', 'Genoa'), ('poet', 'http://www.wikidata.org/entity/Q350103')]
# [('pob', 'http://www.wikidata.org/entity/Q220'), ('cityName', 'Rome'), ('poet', 'http://www.wikidata.org/entity/Q334147')]
# [('pob', 'http://www.wikidata.org/entity/Q220'), ('cityName', 'Rome'), ('poet', 'http://www.wikidata.org/entity/Q334147')]
# 4

# %%
# Get all the poets that were born and attended university in the same city
queryString = """
SELECT ?pob ?cityName (COUNT(DISTINCT(?poet)) as ?count)
WHERE {

   # ?poet wdt:P106 wd:Q49757 .  # BGP for poet
   # ?poet wdt:P172 wd:Q50001 .  # BGP for Italians
   # ?poet wdt:P19 ?pob .        # BGP for place of birth

   # ?poet wdt:P69 ?uni .              #BGP for educated at
   # ?uni wdt:P31/wdt:P279* wd:Q3918.  #BGP for universities
   # ?uni wdt:P131 ?uniCity.           #BGP to retieve the city 

   FILTER(?pob = ?uniCity)

   # ?pob sc:name ?cityName.

}
GROUP BY ?pob ?cityName
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('pob', 'http://www.wikidata.org/entity/Q1449'), ('cityName', 'Genoa'), ('count', '1')]
# [('pob', 'http://www.wikidata.org/entity/Q220'), ('cityName', 'Rome'), ('count', '1')]
# 2

# %% [markdown]
# Final query for this task

# %% [markdown]
# I assume italian potes are the one with `ethnic group` Italians, and I consider as university all intaces of `Q3918` or instances of a subclass.

# %%
# Given a city retrieve the Italian poets that were born or educated there and sums the two counts (removed BGP to impose that the university is in Italy)
queryString = """
SELECT ?city ?cityName SUM(?count) as ?count
WHERE {

    {
        #Get all the cities in which Italian potes were born or studied
        SELECT DISTINCT ?city ?cityName
        WHERE {
        
            {
                # Get all the cities in which Italian poets were born
                SELECT ?city ?cityName
                WHERE {
                   # ?poet wdt:P106 wd:Q49757 .
                   # ?poet wdt:P172 wd:Q50001 .
                   # ?poet wdt:P19 ?city .
                   # ?city sc:name ?cityName.
                }
            } UNION {
                # Get all the cities in which Italian poets attended university
                SELECT ?city ?cityName
                WHERE {
                   # ?poet wdt:P106 wd:Q49757 .        #BGP for poet
                   # ?poet wdt:P172 wd:Q50001 .        #BGP for 'Italians'
                   # ?poet wdt:P69 ?uni .              #BGP for educated at
                   # ?uni wdt:P31/wdt:P279* wd:Q3918.  #BGP for universities
                   # ?uni wdt:P131 ?city.              #BGP to retieve the city 
                   # ?city sc:name ?cityName.
                }
            }
            
        }
    }

    {
        #Number of poets born in the city
        SELECT ?city COUNT(DISTINCT (?poet)) as ?count
        WHERE {
            # ?poet wdt:P106 wd:Q49757 . #BGP for poet
            # ?poet wdt:P172 wd:Q50001 . #BGP for 'Italians'
            # ?poet sc:name ?name.

            # ?poet wdt:P19 ?city .
        }
    }
    UNION 
    {
        #Number of poets that studied in the city
        SELECT ?city COUNT(DISTINCT (?poet)) as ?count
        WHERE {
            # ?poet wdt:P106 wd:Q49757 .        #BGP for poet
            # ?poet wdt:P172 wd:Q50001 .        #BGP for 'Italians'

            # ?poet wdt:P69 ?uni .              #BGP for educated at
            # ?uni wdt:P31/wdt:P279* wd:Q3918.  #BGP for universities
            # ?uni wdt:P131 ?city.              #BGP to retieve the city 
        }
    }

}
GROUP BY ?city ?cityName

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('city', 'http://www.wikidata.org/entity/Q1449'), ('cityName', 'Genoa'), ('count', '4')]
# [('city', 'http://www.wikidata.org/entity/Q219330'), ('cityName', 'Pietrasanta'), ('count', '1')]
# [('city', 'http://www.wikidata.org/entity/Q220'), ('cityName', 'Rome'), ('count', '5')]
# [('city', 'http://www.wikidata.org/entity/Q2634'), ('cityName', 'Naples'), ('count', '1')]
# [('city', 'http://www.wikidata.org/entity/Q6441'), ('cityName', 'Montpellier'), ('count', '1')]
# [('city', 'http://www.wikidata.org/entity/Q279'), ('cityName', 'Modena'), ('count', '1')]
# [('city', 'http://www.wikidata.org/entity/Q52069'), ('cityName', 'Caprese Michelangelo'), ('count', '1')]
# [('city', 'http://www.wikidata.org/entity/Q83362'), ('cityName', 'Recanati'), ('count', '1')]
# [('city', 'http://www.wikidata.org/entity/Q6247'), ('cityName', 'Mantua'), ('count', '1')]
# [('city', 'http://www.wikidata.org/entity/Q20103'), ('cityName', 'Assisi'), ('count', '1')]
# [('city', 'http://www.wikidata.org/entity/Q270613'), ('cityName', 'Celle Ligure'), ('count', '1')]
# [('city', 'http://www.wikidata.org/entity/Q13375'), ('cityName', 'Pisa'), ('count', '1')]
# [('city', 'http://www.wikidata.org/entity/Q586'), ('cityName', 'Bonn'), ('count', '1')]
# [('city', 'http://www.wikidata.org/entity/Q13378'), ('cityName', 'Arezzo'), ('count', '2')]
# [('city', 'http://www.wikidata.org/entity/Q1335'), ('cityName', 'Montevideo'), ('count', '1')]
# [('city', 'http://www.wikidata.org/entity/Q2044'), ('cityName', 'Florence'), ('count', '6')]
# [('city', 'http://www.wikidata.org/entity/Q490'), ('cityName', 'Milan'), ('count', '1')]
# [('city', 'http://www.wikidata.org/entity/Q102634'), ('cityName', 'Monsummano Terme'), ('count', '1')]
# [('city', 'http://www.wikidata.org/entity/Q117032'), ('cityName', 'Pico, Lazio'), ('count', '1')]
# [('city', 'http://www.wikidata.org/entity/Q6259'), ('cityName', 'Pavia'), ('count', '1')]
# [('city', 'http://www.wikidata.org/entity/Q617'), ('cityName', 'Padua'), ('count', '5')]
# [('city', 'http://www.wikidata.org/entity/Q56687351'), ('cityName', 'Valdicastello Carducci'), ('count', '1')]
# [('city', 'http://www.wikidata.org/entity/Q13362'), ('cityName', 'Ferrara'), ('count', '2')]
# [('city', 'http://www.wikidata.org/entity/Q39790'), ('cityName', 'Sangiano'), ('count', '1')]
# [('city', 'http://www.wikidata.org/entity/Q6231'), ('cityName', 'Cremona'), ('count', '1')]
# [('city', 'http://www.wikidata.org/entity/Q87'), ('cityName', 'Alexandria'), ('count', '2')]
# [('city', 'http://www.wikidata.org/entity/Q1722'), ('cityName', 'Dubrovnik'), ('count', '1')]
# [('city', 'http://www.wikidata.org/entity/Q144880'), ('cityName', 'Zakynthos'), ('count', '1')]
# [('city', 'http://www.wikidata.org/entity/Q641'), ('cityName', 'Venice'), ('count', '2')]
# [('city', 'http://www.wikidata.org/entity/Q13360'), ('cityName', 'Reggio Emilia'), ('count', '2')]
# [('city', 'http://www.wikidata.org/entity/Q20454'), ('cityName', 'Saluzzo'), ('count', '1')]
# [('city', 'http://www.wikidata.org/entity/Q13678'), ('cityName', 'Agrigento'), ('count', '1')]
# [('city', 'http://www.wikidata.org/entity/Q6122'), ('cityName', 'Asti'), ('count', '1')]
# [('city', 'http://www.wikidata.org/entity/Q2683'), ('cityName', 'Parma'), ('count', '1')]
# [('city', 'http://www.wikidata.org/entity/Q84'), ('cityName', 'London'), ('count', '1')]
# [('city', 'http://www.wikidata.org/entity/Q6244'), ('cityName', 'Lodi'), ('count', '1')]
# [('city', 'http://www.wikidata.org/entity/Q1891'), ('cityName', 'Bologna'), ('count', '3')]
# 37

# %% [markdown]
# ## Task 8
# Return the italian poets who won the Nobel Prize in Literature (the result set must be poet IRI and label).

# %%
# Get info about significant people
queryString = """
SELECT DISTINCT ?o ?name
WHERE {
    # ?person wdt:P3342 ?o .
    # ?o sc:name ?name.
}
LIMIT 10
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('o', 'http://www.wikidata.org/entity/Q15461487'), ('name', 'Marion Foale')]
# [('o', 'http://www.wikidata.org/entity/Q15734554'), ('name', 'Thora Wigardh')]
# [('o', 'http://www.wikidata.org/entity/Q213675'), ('name', 'Gottfried August Bürger')]
# [('o', 'http://www.wikidata.org/entity/Q4972692'), ('name', 'Anna Petrus')]
# [('o', 'http://www.wikidata.org/entity/Q4990759'), ('name', 'Ria Wägner')]
# [('o', 'http://www.wikidata.org/entity/Q715083'), ('name', 'Joe Murphy')]
# [('o', 'http://www.wikidata.org/entity/Q1450891'), ('name', 'Xavier Niel')]
# [('o', 'http://www.wikidata.org/entity/Q16059906'), ('name', 'Vincenzo Petroccelli')]
# [('o', 'http://www.wikidata.org/entity/Q47044502'), ('name', 'Ida Mitchell Eliot')]
# [('o', 'http://www.wikidata.org/entity/Q98927523'), ('name', 'Marie Duclos Fretageot')]
# 10

# %%
# Get info about significant people that are poet and 'Italians' as 'ethnic group'
queryString = """
SELECT DISTINCT ?o ?name
WHERE {
    # ?person wdt:P3342 ?o .       #significant person
    # ?person wdt:P106 wd:Q49757.  #occupation is 'poet'
    # ?person wdt:P172 wd:Q50001 . #ethnic group is italian
    # ?o sc:name ?name.
}
LIMIT 10
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('o', 'http://www.wikidata.org/entity/Q18197540'), ('name', 'René Dalize')]
# [('o', 'http://www.wikidata.org/entity/Q1401'), ('name', 'Petrarch')]
# [('o', 'http://www.wikidata.org/entity/Q1402'), ('name', 'Giovanni Boccaccio')]
# [('o', 'http://www.wikidata.org/entity/Q100901055'), ('name', 'Carolina Cristofori Piva')]
# 4

# %%
# Get info about significant people that are poet and 'Italians' as 'ethnic group'
queryString = """
SELECT DISTINCT ?o ?name
WHERE {
    # ?person wdt:P3342 ?o .       #significant person
    # ?person wdt:P106 wd:Q49757.  #occupation is 'poet'
    # ?person wdt:P172 wd:Q50001 . #ethnic group is italian
    # ?o sc:name ?name.
}
LIMIT 10
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('o', 'http://www.wikidata.org/entity/Q18197540'), ('name', 'René Dalize')]
# [('o', 'http://www.wikidata.org/entity/Q1401'), ('name', 'Petrarch')]
# [('o', 'http://www.wikidata.org/entity/Q1402'), ('name', 'Giovanni Boccaccio')]
# [('o', 'http://www.wikidata.org/entity/Q100901055'), ('name', 'Carolina Cristofori Piva')]
# 4

# %%
# Get info about significant people
queryString = """
SELECT DISTINCT ?p ?name
WHERE {
    # ?person wdt:P3342 ?o .
    # ?person ?p ?o. 
    # ?p sc:name ?name.
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P108'), ('name', 'employer')]
# [('p', 'http://www.wikidata.org/prop/direct/P112'), ('name', 'founded by')]
# [('p', 'http://www.wikidata.org/prop/direct/P175'), ('name', 'performer')]
# [('p', 'http://www.wikidata.org/prop/direct/P3342'), ('name', 'significant person')]
# [('p', 'http://www.wikidata.org/prop/direct/P488'), ('name', 'chairperson')]
# [('p', 'http://www.wikidata.org/prop/direct/P737'), ('name', 'influenced by')]
# [('p', 'http://www.wikidata.org/prop/direct/P802'), ('name', 'student')]
# [('p', 'http://www.wikidata.org/prop/direct/P453'), ('name', 'character role')]
# [('p', 'http://www.wikidata.org/prop/direct/P1038'), ('name', 'relative')]
# [('p', 'http://www.wikidata.org/prop/direct/P1066'), ('name', 'student of')]
# [('p', 'http://www.wikidata.org/prop/direct/P127'), ('name', 'owned by')]
# [('p', 'http://www.wikidata.org/prop/direct/P26'), ('name', 'spouse')]
# [('p', 'http://www.wikidata.org/prop/direct/P451'), ('name', 'unmarried partner')]
# [('p', 'http://www.wikidata.org/prop/direct/P1327'), ('name', 'partner in business or sport')]
# [('p', 'http://www.wikidata.org/prop/direct/P184'), ('name', 'doctoral advisor')]
# [('p', 'http://www.wikidata.org/prop/direct/P3764'), ('name', 'pole position')]
# [('p', 'http://www.wikidata.org/prop/direct/P5053'), ('name', 'fastest lap')]
# [('p', 'http://www.wikidata.org/prop/direct/P3448'), ('name', 'stepparent')]
# [('p', 'http://www.wikidata.org/prop/direct/P1343'), ('name', 'described by source')]
# [('p', 'http://www.wikidata.org/prop/direct/P1346'), ('name', 'winner')]
# [('p', 'http://www.wikidata.org/prop/direct/P149'), ('name', 'architectural style')]
# [('p', 'http://www.wikidata.org/prop/direct/P6379'), ('name', 'has works in the collection')]
# [('p', 'http://www.wikidata.org/prop/direct/P263'), ('name', 'official residence')]
# [('p', 'http://www.wikidata.org/prop/direct/P138'), ('name', 'named after')]
# [('p', 'http://www.wikidata.org/prop/direct/P19'), ('name', 'place of birth')]
# [('p', 'http://www.wikidata.org/prop/direct/P2546'), ('name', 'sidekick of')]
# [('p', 'http://www.wikidata.org/prop/direct/P3091'), ('name', 'mount')]
# [('p', 'http://www.wikidata.org/prop/direct/P3373'), ('name', 'sibling')]
# [('p', 'http://www.wikidata.org/prop/direct/P7047'), ('name', 'enemy of')]
# [('p', 'http://www.wikidata.org/prop/direct/P8004'), ('name', 'ordered by')]
# [('p', 'http://www.wikidata.org/prop/direct/P1591'), ('name', 'defendant')]
# [('p', 'http://www.wikidata.org/prop/direct/P161'), ('name', 'cast member')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('name', 'has part')]
# [('p', 'http://www.wikidata.org/prop/direct/P1269'), ('name', 'facet of')]
# [('p', 'http://www.wikidata.org/prop/direct/P22'), ('name', 'father')]
# [('p', 'http://www.wikidata.org/prop/direct/P674'), ('name', 'characters')]
# [('p', 'http://www.wikidata.org/prop/direct/P1535'), ('name', 'used by')]
# [('p', 'http://www.wikidata.org/prop/direct/P162'), ('name', 'producer')]
# [('p', 'http://www.wikidata.org/prop/direct/P169'), ('name', 'chief executive officer')]
# [('p', 'http://www.wikidata.org/prop/direct/P3320'), ('name', 'board member')]
# [('p', 'http://www.wikidata.org/prop/direct/P61'), ('name', 'discoverer or inventor')]
# [('p', 'http://www.wikidata.org/prop/direct/P710'), ('name', 'participant')]
# [('p', 'http://www.wikidata.org/prop/direct/P84'), ('name', 'architect')]
# [('p', 'http://www.wikidata.org/prop/direct/P1037'), ('name', 'director / manager')]
# [('p', 'http://www.wikidata.org/prop/direct/P50'), ('name', 'author')]
# [('p', 'http://www.wikidata.org/prop/direct/P98'), ('name', 'editor')]
# [('p', 'http://www.wikidata.org/prop/direct/P1268'), ('name', 'represents')]
# [('p', 'http://www.wikidata.org/prop/direct/P287'), ('name', 'designed by')]
# [('p', 'http://www.wikidata.org/prop/direct/P4791'), ('name', 'commanded by')]
# [('p', 'http://www.wikidata.org/prop/direct/P361'), ('name', 'part of')]
# [('p', 'http://www.wikidata.org/prop/direct/P1889'), ('name', 'different from')]
# [('p', 'http://www.wikidata.org/prop/direct/P921'), ('name', 'main subject')]
# [('p', 'http://www.wikidata.org/prop/direct/P157'), ('name', 'killed by')]
# [('p', 'http://www.wikidata.org/prop/direct/P551'), ('name', 'residence')]
# [('p', 'http://www.wikidata.org/prop/direct/P5769'), ('name', 'editor-in-chief')]
# [('p', 'http://www.wikidata.org/prop/direct/P941'), ('name', 'inspired by')]
# [('p', 'http://www.wikidata.org/prop/direct/P195'), ('name', 'collection')]
# [('p', 'http://www.wikidata.org/prop/direct/P800'), ('name', 'notable work')]
# [('p', 'http://www.wikidata.org/prop/direct/P4675'), ('name', 'appears in the form of')]
# [('p', 'http://www.wikidata.org/prop/direct/P170'), ('name', 'creator')]
# [('p', 'http://www.wikidata.org/prop/direct/P460'), ('name', 'said to be the same as')]
# [('p', 'http://www.wikidata.org/prop/direct/P4292'), ('name', 'possessed by spirit')]
# [('p', 'http://www.wikidata.org/prop/direct/P1652'), ('name', 'referee')]
# [('p', 'http://www.wikidata.org/prop/direct/P3975'), ('name', 'secretary general')]
# [('p', 'http://www.wikidata.org/prop/direct/P3205'), ('name', 'patient of')]
# [('p', 'http://www.wikidata.org/prop/direct/P6149'), ('name', 'running mate')]
# [('p', 'http://www.wikidata.org/prop/direct/P3095'), ('name', 'practiced by')]
# [('p', 'http://www.wikidata.org/prop/direct/P155'), ('name', 'follows')]
# [('p', 'http://www.wikidata.org/prop/direct/P156'), ('name', 'followed by')]
# [('p', 'http://www.wikidata.org/prop/direct/P40'), ('name', 'child')]
# [('p', 'http://www.wikidata.org/prop/direct/P676'), ('name', 'lyrics by')]
# [('p', 'http://www.wikidata.org/prop/direct/P859'), ('name', 'sponsor')]
# [('p', 'http://www.wikidata.org/prop/direct/P86'), ('name', 'composer')]
# [('p', 'http://www.wikidata.org/prop/direct/P1431'), ('name', 'executive producer')]
# [('p', 'http://www.wikidata.org/prop/direct/P58'), ('name', 'screenwriter')]
# [('p', 'http://www.wikidata.org/prop/direct/P945'), ('name', 'allegiance')]
# [('p', 'http://www.wikidata.org/prop/direct/P1877'), ('name', 'after a work by')]
# [('p', 'http://www.wikidata.org/prop/direct/P1789'), ('name', 'chief operating officer')]
# [('p', 'http://www.wikidata.org/prop/direct/P1875'), ('name', 'represented by')]
# [('p', 'http://www.wikidata.org/prop/direct/P25'), ('name', 'mother')]
# [('p', 'http://www.wikidata.org/prop/direct/P7084'), ('name', 'related category')]
# [('p', 'http://www.wikidata.org/prop/direct/P1290'), ('name', 'godparent')]
# [('p', 'http://www.wikidata.org/prop/direct/P6'), ('name', 'head of government')]
# [('p', 'http://www.wikidata.org/prop/direct/P3174'), ('name', 'art director')]
# [('p', 'http://www.wikidata.org/prop/direct/P2389'), ('name', 'organization directed by the office or position')]
# [('p', 'http://www.wikidata.org/prop/direct/P6241'), ('name', 'collection creator')]
# [('p', 'http://www.wikidata.org/prop/direct/P466'), ('name', 'occupant')]
# [('p', 'http://www.wikidata.org/prop/direct/P971'), ('name', 'category combines topics')]
# [('p', 'http://www.wikidata.org/prop/direct/P1830'), ('name', 'owner of')]
# [('p', 'http://www.wikidata.org/prop/direct/P8032'), ('name', 'victim')]
# 90

# %%
# Get info about 'winning'
queryString = """
SELECT DISTINCT ?sname ?oname
WHERE {
    # ?o wdt:P1346 ?s. 
    # ?s sc:name ?sname.
    # ?o sc:name ?oname.
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('sname', 'Taliana Vargas'), ('oname', 'Miss Colombia 2007')]
# [('sname', 'Illya Kvasha'), ('oname', "2013 European Diving Championships – men's 1 metre springboard")]
# [('sname', 'Egoitz García'), ('oname', '2014 Tropicale Amissa Bongo')]
# [('sname', 'Guillaume Van Keirsbulck'), ('oname', '2014 Tour of Qatar')]
# [('sname', 'Jason Day'), ('oname', '2014 WGC-Accenture Match Play Championship')]
# [('sname', 'Bentonville High School'), ('oname', '2014 Arkansas High School 7A Boys Soccer Season')]
# [('sname', 'UE Engordany'), ('oname', '2013–14 Segona Divisió')]
# [('sname', 'Bert Pronk'), ('oname', '1977 Tour de Suisse')]
# [('sname', 'Pierre Barthès'), ('oname', "1970 US Open – Men's Doubles")]
# [('sname', 'BC Zepter Vienna'), ('oname', '2012–13 Österreichische Basketball Bundesliga')]
# [('sname', 'Dylan Girdlestone'), ('oname', 'Tour du Rwanda 2013')]
# [('sname', 'Sven Van Luijk'), ('oname', '2012 Czech Cycling Tour')]
# [('sname', 'Kristian Haugaard'), ('oname', '2013 Czech Cycling Tour')]
# [('sname', 'Sven Van Luijk'), ('oname', '2013 Czech Cycling Tour')]
# [('sname', 'Maxime Vantomme'), ('oname', '2014 Le Samyn')]
# [('sname', 'Alexey Tsatevich'), ('oname', '2014 Le Samyn')]
# [('sname', 'Margarita Gasparyan'), ('oname', '2014 Open GDF Suez Seine-et-Marne – doubles')]
# [('sname', 'Anna Karolína Schmiedlová'), ('oname', '2014 The Oaks Club Challenger – singles')]
# [('sname', 'Rika Fujiwara'), ('oname', '2014 The Oaks Club Challenger – doubles')]
# [('sname', 'Jasem Vishgahi'), ('oname', "karate at the 2006 Asian Games – men's kumite 75 kg")]
# [('sname', 'Hossein Rouhani'), ('oname', "karate at the 2006 Asian Games – men's kumite 60 kg")]
# [('sname', 'Elinor Barker'), ('oname', "2011 UCI Road World Championships – Women's junior time trial")]
# [('sname', 'Jessica Allen'), ('oname', "2011 UCI Road World Championships – Women's junior time trial")]
# [('sname', 'Mieke Kröger'), ('oname', "2011 UCI Road World Championships – Women's junior time trial")]
# [('sname', 'Bibian Mentel'), ('oname', "alpine skiing at the 2014 Winter Paralympics – women's snowboard cross")]
# [('sname', 'Ueli Sutter'), ('oname', '1978 Tour de Suisse')]
# [('sname', 'Mike Schloesser'), ('oname', '2016 Archery World Cup')]
# [('sname', 'Elinor Barker'), ('oname', "2012 UCI Road World Championships – Women's junior time trial")]
# [('sname', 'Alexey Tsatevich'), ('oname', '2013 Le Samyn')]
# [('sname', 'Dylan Girdlestone'), ('oname', 'Tour du Rwanda 2012')]
# [('sname', 'Eileen Bennett Whittingstall'), ('oname', "1928 French Championships – Women's Doubles")]
# [('sname', 'Alejandra Usquiano'), ('oname', '2013 FITA Archery World Cup')]
# [('sname', 'Gu Li'), ('oname', '21st Fujitsu Cup')]
# [('sname', 'T1'), ('oname', 'League of Legends Champions Winter 2013-2014')]
# [('sname', 'Jeff Green'), ('oname', '2000 NASCAR Busch Series')]
# [('sname', 'Radu Albot'), ('oname', '2014 Mersin Cup – doubles')]
# [('sname', 'Ted Ray'), ('oname', '1912 Open Championship')]
# [('sname', 'Graham Newberry'), ('oname', "2018 British Figure Skating Championships - senior men's singles")]
# [('sname', 'Mayuko Hagiwara'), ('oname', "cycling at the 2006 Asian Games – women's road race")]
# [('sname', 'Dunshaughlin GAA'), ('oname', '2000 Meath Senior Football Championship')]
# [('sname', 'Seneschalstown GAA'), ('oname', '2007 Meath Senior Football Championship')]
# [('sname', 'Tom Rolfe'), ('oname', '1965 Preakness Stakes')]
# [('sname', 'Kornelia Ender'), ('oname', "swimming at the 1973 World Aquatics Championships – women's 100 metre freestyle")]
# [('sname', 'Igualada HC'), ('oname', '1995–96 Roller Hockey Champions Cup')]
# [('sname', 'Shunichi Kawano'), ('oname', "wrestling at the 1962 Asian Games – men's Greco-Roman 87 kg")]
# [('sname', 'Hwang Hee-tae'), ('oname', "judo at the 2006 Asian Games – men's 90 kg")]
# [('sname', 'Takashi Ono'), ('oname', "judo at the 2010 Asian Games – men's 90 kg")]
# [('sname', 'Abdullah Al-Rashidi'), ('oname', "shooting at the 2010 Asian Games – men's skeet")]
# [('sname', 'Chutchawal Khawlaor'), ('oname', "taekwondo at the 2010 Asian Games – men's 54 kg")]
# [('sname', 'Mohammad Bagheri Motamed'), ('oname', "taekwondo at the 2010 Asian Games – men's 68 kg")]
# [('sname', 'Hsiao Mei-yu'), ('oname', "cycling at the 2010 Asian Games – women's road race")]
# [('sname', 'Azizulhasni Awang'), ('oname', "cycling at the 2010 Asian Games – men's keirin")]
# [('sname', 'Chan Chun Hing'), ('oname', "cycling at the 2010 Asian Games – men's cross-country")]
# [('sname', 'Hong Ok-song'), ('oname', "judo at the 2002 Asian Games – women's 57 kg")]
# [('sname', 'Lees García'), ('oname', 'Miss Grand International 2014')]
# [('sname', 'Naama Kasry'), ('oname', 'Survivor 10: The Caribbean')]
# [('sname', 'Karen Soto'), ('oname', 'Miss Venezuela World 2013')]
# [('sname', 'Thomas Munkelt'), ('oname', "1982 European Athletics Championships – men's 110 metres hurdles")]
# [('sname', 'Abdullah Al-Rashidi'), ('oname', "shooting at the 2014 Asian Games – men's skeet")]
# [('sname', 'Ashok Venkitaraman'), ('oname', 'Basser Global Prize')]
# [('sname', 'Dylan Teuns'), ('oname', '2014 Omloop Het Nieuwsblad Beloften')]
# [('sname', 'Roberto Bautista Agut'), ('oname', '2014 MercedesCup – singles')]
# [('sname', 'Freddy Loix'), ('oname', '2014 Ypres Rally')]
# [('sname', 'Klaas Sys'), ('oname', '2010 Omloop Het Nieuwsblad Beloften')]
# [('sname', 'Kemar Bailey-Cole'), ('oname', "athletics at the 2014 Commonwealth Games – men's 100 metres")]
# [('sname', 'Lara Arruabarrena'), ('oname', '2014 Seguros Bolívar Open Bogotá – doubles')]
# [('sname', 'Alexis Camacho'), ('oname', '2014 Vuelta a Colombia')]
# [('sname', 'Aldemar Reyes'), ('oname', '2014 Vuelta a Colombia')]
# [('sname', 'Marvin Angarita'), ('oname', '2014 Vuelta a Colombia')]
# [('sname', 'Walter Pedraza'), ('oname', '2014 Vuelta a Colombia')]
# [('sname', 'Christelle Daunay'), ('oname', "2014 European Athletics Championships – Women's Marathon")]
# [('sname', 'Eilidh Doyle'), ('oname', "2014 European Athletics Championships – women's 400 metres hurdles")]
# [('sname', 'Kariem Hussein'), ('oname', "2014 European Athletics Championships – men's 400 metres hurdles")]
# [('sname', 'Jozef Kovalík'), ('oname', '2014 Maserati Challenger – singles')]
# [('sname', 'Bahodirjon Sultonov'), ('oname', "boxing at the 2006 Asian Games – men's 57 kg")]
# [('sname', 'Bakhyt Sarsekbayev'), ('oname', "boxing at the 2006 Asian Games – men's 69 kg")]
# [('sname', 'Ali Mazaheri'), ('oname', "boxing at the 2006 Asian Games – men's 91 kg")]
# [('sname', 'Daria Korobova'), ('oname', 'synchronised swimming at the 2014 European Aquatics Championships – duet routine')]
# [('sname', 'Katherine Haik'), ('oname', 'Miss Teen USA 2015')]
# [('sname', 'Mauricio Ortega'), ('oname', '2015 Vuelta a Colombia')]
# [('sname', 'Geoff Hunt'), ('oname', "1976 Men's World Open Squash Championship")]
# [('sname', 'Bohdan Bondarenko'), ('oname', "2014 European Athletics Championships – men's high jump")]
# [('sname', 'Fran Halsall'), ('oname', "swimming at the 2014 European Aquatics Championships – women's 50 metre backstroke")]
# [('sname', 'Adam Peaty'), ('oname', "swimming at the 2014 European Aquatics Championships – men's 50 metre breaststroke")]
# [('sname', 'Nadezhda Bazhina'), ('oname', "diving at the 2014 European Aquatics Championships – women's 3 m springboard")]
# [('sname', "2016 World Wrestling Championships – women's freestyle 55 kg"), ('oname', 'Mayu Mukaida')]
# [('sname', "2018 World Wrestling Championships – Women's freestyle 55 kg"), ('oname', 'Mayu Mukaida')]
# [('sname', 'Jochem Hoekstra'), ('oname', '2014 Grand Prix des Marbriers')]
# [('sname', 'Yann Guyot'), ('oname', '2014 Grand Prix des Marbriers')]
# [('sname', 'Kévin Lalouette'), ('oname', '2014 Grand Prix des Marbriers')]
# [('sname', 'Laurent Maistret'), ('oname', 'Koh-Lanta : The New Edition')]
# [('sname', 'Alois Hudec'), ('oname', "gymnastics at the 1936 Summer Olympics – men's rings")]
# [('sname', 'Anita Bärwirth'), ('oname', "gymnastics at the 1936 Summer Olympics – women's artistic team all-around")]
# [('sname', 'Yaşar Erkan'), ('oname', "wrestling at the 1936 Summer Olympics – men's Greco-Roman featherweight")]
# [('sname', 'Karl-Erik Nilsson'), ('oname', "wrestling at the 1948 Summer Olympics – men's Greco-Roman light heavyweight")]
# [('sname', 'Kustaa Pihlajamäki'), ('oname', "wrestling at the 1936 Summer Olympics – men's freestyle featherweight")]
# [('sname', 'John Doeg'), ('oname', "1930 U.S. National Championships – Men's Singles")]
# [('sname', 'Nancy Richey'), ('oname', '1972 Virginia Slims of Washington – singles')]
# [('sname', 'Stéphane Bonsergent'), ('oname', '2009 Tro-Bro Leon')]
# [('sname', 'Will Routley'), ('oname', '2011 Tro-Bro Leon')]
# 100

# %%
# Get info about 'winning'
queryString = """
SELECT DISTINCT ?sname ?oname
WHERE {
    # ?o wdt:P1346 ?s. 
    # ?s sc:name ?sname.
    # ?o sc:name ?oname.
    FILTER REGEX(?o, "[Nn]obel")
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# Empty

# %%
# Get info about prizes won by potes
queryString = """
SELECT DISTINCT ?sname ?prize
WHERE {
    # ?poet wdt:P106 wd:Q49757 .
    # ?prize wdt:P1346 ?poet. 
    # ?prize sc:name ?sname.
}
LIMIT 10
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('sname', 'Mercury Prize'), ('prize', 'http://www.wikidata.org/entity/Q501876')]
# [('sname', 'Jakob Wassermann Prize'), ('prize', 'http://www.wikidata.org/entity/Q1678870')]
# [('sname', 'Filmfare Award for Best Story'), ('prize', 'http://www.wikidata.org/entity/Q1414504')]
# [('sname', 'Filmfare Award for Best Dialogue'), ('prize', 'http://www.wikidata.org/entity/Q1414514')]
# [('sname', 'Ruth Lilly Poetry Prize'), ('prize', 'http://www.wikidata.org/entity/Q728657')]
# [('sname', 'Dos Passos Prize'), ('prize', 'http://www.wikidata.org/entity/Q2439701')]
# [('sname', 'Nobel Prize in Literature'), ('prize', 'http://www.wikidata.org/entity/Q37922')]
# [('sname', 'Mercè Rodoreda Award'), ('prize', 'http://www.wikidata.org/entity/Q11700304')]
# [('sname', 'Grammy Award for Best Spoken Word Album'), ('prize', 'http://www.wikidata.org/entity/Q5593890')]
# [('sname', 'De Gyldne Laurbær'), ('prize', 'http://www.wikidata.org/entity/Q1179930')]
# 10

# %%
# Get info about prizes won by potes
queryString = """
SELECT DISTINCT ?sname ?prize
WHERE {
    # ?poet wdt:P106 wd:Q49757 .
    # ?prize wdt:P1346 ?poet. 
    # ?prize sc:name ?sname.
}
LIMIT 10
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('sname', 'Mercury Prize'), ('prize', 'http://www.wikidata.org/entity/Q501876')]
# [('sname', 'Jakob Wassermann Prize'), ('prize', 'http://www.wikidata.org/entity/Q1678870')]
# [('sname', 'Filmfare Award for Best Story'), ('prize', 'http://www.wikidata.org/entity/Q1414504')]
# [('sname', 'Filmfare Award for Best Dialogue'), ('prize', 'http://www.wikidata.org/entity/Q1414514')]
# [('sname', 'Ruth Lilly Poetry Prize'), ('prize', 'http://www.wikidata.org/entity/Q728657')]
# [('sname', 'Dos Passos Prize'), ('prize', 'http://www.wikidata.org/entity/Q2439701')]
# [('sname', 'Nobel Prize in Literature'), ('prize', 'http://www.wikidata.org/entity/Q37922')]
# [('sname', 'Mercè Rodoreda Award'), ('prize', 'http://www.wikidata.org/entity/Q11700304')]
# [('sname', 'Grammy Award for Best Spoken Word Album'), ('prize', 'http://www.wikidata.org/entity/Q5593890')]
# [('sname', 'De Gyldne Laurbær'), ('prize', 'http://www.wikidata.org/entity/Q1179930')]
# 10

# %%
# Get all italian potes
queryString = """
SELECT DISTINCT ?person ?name
WHERE {
    # ?person wdt:P106 wd:Q49757.    #occupation is 'poet'
    # ?person wdt:P172 wd:Q50001 .   #ethnic group is italian
    # ?person sc:name ?name.
}
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('person', 'http://www.wikidata.org/entity/Q296272'), ('name', 'Pietro Aretino')]
# [('person', 'http://www.wikidata.org/entity/Q982512'), ('name', 'Giuseppe Giusti')]
# [('person', 'http://www.wikidata.org/entity/Q55433'), ('name', 'Michelangelo Antonioni')]
# [('person', 'http://www.wikidata.org/entity/Q83321'), ('name', 'Giacomo Casanova')]
# [('person', 'http://www.wikidata.org/entity/Q182046'), ('name', 'Leon Battista Alberti')]
# [('person', 'http://www.wikidata.org/entity/Q48900'), ('name', 'Ludovico Ariosto')]
# [('person', 'http://www.wikidata.org/entity/Q165534'), ('name', 'Carlo Goldoni')]
# [('person', 'http://www.wikidata.org/entity/Q7803'), ('name', 'Bronzino')]
# [('person', 'http://www.wikidata.org/entity/Q982387'), ('name', 'Giovanni Capurro')]
# [('person', 'http://www.wikidata.org/entity/Q1067'), ('name', 'Dante Alighieri')]
# [('person', 'http://www.wikidata.org/entity/Q346250'), ('name', 'Ada Negri')]
# [('person', 'http://www.wikidata.org/entity/Q166234'), ('name', 'Ugo Foscolo')]
# [('person', 'http://www.wikidata.org/entity/Q5592'), ('name', 'Michelangelo')]
# [('person', 'http://www.wikidata.org/entity/Q676555'), ('name', 'Francis of Assisi')]
# [('person', 'http://www.wikidata.org/entity/Q350103'), ('name', 'Felice Romani')]
# [('person', 'http://www.wikidata.org/entity/Q560541'), ('name', 'Tommaso Landolfi')]
# [('person', 'http://www.wikidata.org/entity/Q29473'), ('name', 'Pietro Metastasio')]
# [('person', 'http://www.wikidata.org/entity/Q186748'), ('name', 'Dante Gabriel Rossetti')]
# [('person', 'http://www.wikidata.org/entity/Q43440'), ('name', 'Giosuè Carducci')]
# [('person', 'http://www.wikidata.org/entity/Q53009'), ('name', 'Bernardo Bertolucci')]
# [('person', 'http://www.wikidata.org/entity/Q133855'), ('name', 'Guillaume Apollinaire')]
# [('person', 'http://www.wikidata.org/entity/Q1401'), ('name', 'Petrarch')]
# [('person', 'http://www.wikidata.org/entity/Q311802'), ('name', 'Giuseppe Ungaretti')]
# [('person', 'http://www.wikidata.org/entity/Q1403'), ('name', 'Luigi Pirandello')]
# [('person', 'http://www.wikidata.org/entity/Q296244'), ('name', 'Vittorio Alfieri')]
# [('person', 'http://www.wikidata.org/entity/Q765'), ('name', 'Dario Fo')]
# [('person', 'http://www.wikidata.org/entity/Q8243562'), ('name', 'Basilio Boggiero Spotorno')]
# [('person', 'http://www.wikidata.org/entity/Q172599'), ('name', 'Giacomo Leopardi')]
# [('person', 'http://www.wikidata.org/entity/Q216582'), ('name', 'Filippo Tommaso Marinettiz6eztfzitryxi')]
# [('person', 'http://www.wikidata.org/entity/Q1402'), ('name', 'Giovanni Boccaccio')]
# [('person', 'http://www.wikidata.org/entity/Q334147'), ('name', 'Julius Evola')]
# [('person', 'http://www.wikidata.org/entity/Q3094064'), ('name', 'Gabriele Faerno')]
# [('person', 'http://www.wikidata.org/entity/Q435151'), ('name', 'Silvio Pellico')]
# [('person', 'http://www.wikidata.org/entity/Q5559404'), ('name', 'Alessandro Arnaboldi')]
# [('person', 'http://www.wikidata.org/entity/Q1334439'), ('name', 'Alessandro Striggio the Younger')]
# [('person', 'http://www.wikidata.org/entity/Q982845'), ('name', 'Moshe Chaim Luzzatto')]
# [('person', 'http://www.wikidata.org/entity/Q317588'), ('name', 'Ivan Gundulić')]
# [('person', 'http://www.wikidata.org/entity/Q2252971'), ('name', 'Vincenzo da Filicaja')]
# [('person', 'http://www.wikidata.org/entity/Q7368989'), ('name', 'Rosita Melo')]
# [('person', 'http://www.wikidata.org/entity/Q33895590'), ('name', 'Francesco Cassoli')]
# 40

# %%
# Get all italian potes that won prizes with their prizes
queryString = """
SELECT DISTINCT ?person ?name ?prize ?pname
WHERE {
    # ?person wdt:P106 wd:Q49757.    #occupation is 'poet'
    # ?person wdt:P172 wd:Q50001 .   #ethnic group is italian
    # ?person sc:name ?name.
    
    # ?person wdt:P166 ?prize.
    # ?prize sc:name ?pname.
    
}
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('person', 'http://www.wikidata.org/entity/Q55433'), ('name', 'Michelangelo Antonioni'), ('prize', 'http://www.wikidata.org/entity/Q7650000'), ('pname', 'Sutherland Trophy')]
# [('person', 'http://www.wikidata.org/entity/Q53009'), ('name', 'Bernardo Bertolucci'), ('prize', 'http://www.wikidata.org/entity/Q7650000'), ('pname', 'Sutherland Trophy')]
# [('person', 'http://www.wikidata.org/entity/Q216582'), ('name', 'Filippo Tommaso Marinettiz6eztfzitryxi'), ('prize', 'http://www.wikidata.org/entity/Q1541614'), ('pname', 'War Merit Cross (Italy)')]
# [('person', 'http://www.wikidata.org/entity/Q560541'), ('name', 'Tommaso Landolfi'), ('prize', 'http://www.wikidata.org/entity/Q1526935'), ('pname', 'Viareggio Prize')]
# [('person', 'http://www.wikidata.org/entity/Q560541'), ('name', 'Tommaso Landolfi'), ('prize', 'http://www.wikidata.org/entity/Q788568'), ('pname', 'Bagutta Prize')]
# [('person', 'http://www.wikidata.org/entity/Q53009'), ('name', 'Bernardo Bertolucci'), ('prize', 'http://www.wikidata.org/entity/Q674146'), ('pname', 'Leopard of Honour')]
# [('person', 'http://www.wikidata.org/entity/Q560541'), ('name', 'Tommaso Landolfi'), ('prize', 'http://www.wikidata.org/entity/Q731542'), ('pname', 'Strega Prize')]
# [('person', 'http://www.wikidata.org/entity/Q765'), ('name', 'Dario Fo'), ('prize', 'http://www.wikidata.org/entity/Q9052807'), ('pname', 'Orden al Mérito Docente y Cultural Gabriela Mistral')]
# [('person', 'http://www.wikidata.org/entity/Q346250'), ('name', 'Ada Negri'), ('prize', 'http://www.wikidata.org/entity/Q27949746'), ('pname', 'Premio Giannina Milli')]
# [('person', 'http://www.wikidata.org/entity/Q53009'), ('name', 'Bernardo Bertolucci'), ('prize', 'http://www.wikidata.org/entity/Q103360'), ('pname', 'Academy Award for Best Director')]
# [('person', 'http://www.wikidata.org/entity/Q53009'), ('name', 'Bernardo Bertolucci'), ('prize', 'http://www.wikidata.org/entity/Q107258'), ('pname', 'Academy Award for Best Writing, Adapted Screenplay')]
# [('person', 'http://www.wikidata.org/entity/Q53009'), ('name', 'Bernardo Bertolucci'), ('prize', 'http://www.wikidata.org/entity/Q139184'), ('pname', 'BAFTA Award for Best Film')]
# [('person', 'http://www.wikidata.org/entity/Q53009'), ('name', 'Bernardo Bertolucci'), ('prize', 'http://www.wikidata.org/entity/Q14539884'), ('pname', 'Grand Officer of the Order of Merit of the Italian Republic')]
# [('person', 'http://www.wikidata.org/entity/Q55433'), ('name', 'Michelangelo Antonioni'), ('prize', 'http://www.wikidata.org/entity/Q14539974'), ('pname', 'Knight Grand Cross of the Order of Merit of the Italian Republic')]
# [('person', 'http://www.wikidata.org/entity/Q55433'), ('name', 'Michelangelo Antonioni'), ('prize', 'http://www.wikidata.org/entity/Q154590'), ('pname', 'Golden Bear')]
# [('person', 'http://www.wikidata.org/entity/Q55433'), ('name', 'Michelangelo Antonioni'), ('prize', 'http://www.wikidata.org/entity/Q179808'), ('pname', "Palme d'Or")]
# [('person', 'http://www.wikidata.org/entity/Q53009'), ('name', 'Bernardo Bertolucci'), ('prize', 'http://www.wikidata.org/entity/Q17985761'), ('pname', 'star on Hollywood Walk of Fame')]
# [('person', 'http://www.wikidata.org/entity/Q55433'), ('name', 'Michelangelo Antonioni'), ('prize', 'http://www.wikidata.org/entity/Q209459'), ('pname', 'Golden Lion')]
# [('person', 'http://www.wikidata.org/entity/Q216582'), ('name', 'Filippo Tommaso Marinettiz6eztfzitryxi'), ('prize', 'http://www.wikidata.org/entity/Q2454427'), ('pname', 'Victory Medal')]
# [('person', 'http://www.wikidata.org/entity/Q43440'), ('name', 'Giosuè Carducci'), ('prize', 'http://www.wikidata.org/entity/Q37922'), ('pname', 'Nobel Prize in Literature')]
# [('person', 'http://www.wikidata.org/entity/Q1403'), ('name', 'Luigi Pirandello'), ('prize', 'http://www.wikidata.org/entity/Q37922'), ('pname', 'Nobel Prize in Literature')]
# [('person', 'http://www.wikidata.org/entity/Q765'), ('name', 'Dario Fo'), ('prize', 'http://www.wikidata.org/entity/Q37922'), ('pname', 'Nobel Prize in Literature')]
# [('person', 'http://www.wikidata.org/entity/Q55433'), ('name', 'Michelangelo Antonioni'), ('prize', 'http://www.wikidata.org/entity/Q514445'), ('pname', 'European Film Academy Lifetime Achievement Award')]
# [('person', 'http://www.wikidata.org/entity/Q53009'), ('name', 'Bernardo Bertolucci'), ('prize', 'http://www.wikidata.org/entity/Q514445'), ('pname', 'European Film Academy Lifetime Achievement Award')]
# [('person', 'http://www.wikidata.org/entity/Q53009'), ('name', 'Bernardo Bertolucci'), ('prize', 'http://www.wikidata.org/entity/Q5280675'), ('pname', 'Directors Guild of America Award for Outstanding Directing – Feature Film')]
# [('person', 'http://www.wikidata.org/entity/Q765'), ('name', 'Dario Fo'), ('prize', 'http://www.wikidata.org/entity/Q55139818'), ('pname', 'honorary doctorate of the Vrije Universiteit Brussel')]
# [('person', 'http://www.wikidata.org/entity/Q53009'), ('name', 'Bernardo Bertolucci'), ('prize', 'http://www.wikidata.org/entity/Q586356'), ('pname', 'Golden Globe Award for Best Director')]
# [('person', 'http://www.wikidata.org/entity/Q53009'), ('name', 'Bernardo Bertolucci'), ('prize', 'http://www.wikidata.org/entity/Q900414'), ('pname', 'César Award for Best Foreign Film')]
# [('person', 'http://www.wikidata.org/entity/Q765'), ('name', 'Dario Fo'), ('prize', 'http://www.wikidata.org/entity/Q963068'), ('pname', 'Sonning Prize')]
# [('person', 'http://www.wikidata.org/entity/Q55433'), ('name', 'Michelangelo Antonioni'), ('prize', 'http://www.wikidata.org/entity/Q3703463'), ('pname', 'David di Donatello for Best Director')]
# [('person', 'http://www.wikidata.org/entity/Q53009'), ('name', 'Bernardo Bertolucci'), ('prize', 'http://www.wikidata.org/entity/Q3703463'), ('pname', 'David di Donatello for Best Director')]
# [('person', 'http://www.wikidata.org/entity/Q55433'), ('name', 'Michelangelo Antonioni'), ('prize', 'http://www.wikidata.org/entity/Q727328'), ('pname', 'Academy Honorary Award')]
# [('person', 'http://www.wikidata.org/entity/Q53009'), ('name', 'Bernardo Bertolucci'), ('prize', 'http://www.wikidata.org/entity/Q768476'), ('pname', 'David di Donatello for Best Film')]
# [('person', 'http://www.wikidata.org/entity/Q53009'), ('name', 'Bernardo Bertolucci'), ('prize', 'http://www.wikidata.org/entity/Q3753203'), ('pname', 'Gold Medal of Merit in the Fine Arts (Spain)')]
# [('person', 'http://www.wikidata.org/entity/Q311802'), ('name', 'Giuseppe Ungaretti'), ('prize', 'http://www.wikidata.org/entity/Q580574'), ('pname', 'Neustadt International Prize for Literature')]
# [('person', 'http://www.wikidata.org/entity/Q216582'), ('name', 'Filippo Tommaso Marinettiz6eztfzitryxi'), ('prize', 'http://www.wikidata.org/entity/Q846482'), ('pname', 'War Cross for Military Valour')]
# [('person', 'http://www.wikidata.org/entity/Q83321'), ('name', 'Giacomo Casanova'), ('prize', 'http://www.wikidata.org/entity/Q93716'), ('pname', 'Order of the Golden Spur')]
# [('person', 'http://www.wikidata.org/entity/Q55433'), ('name', 'Michelangelo Antonioni'), ('prize', 'http://www.wikidata.org/entity/Q1315008'), ('pname', 'National Society of Film Critics Award for Best Director')]
# [('person', 'http://www.wikidata.org/entity/Q53009'), ('name', 'Bernardo Bertolucci'), ('prize', 'http://www.wikidata.org/entity/Q1315008'), ('pname', 'National Society of Film Critics Award for Best Director')]
# [('person', 'http://www.wikidata.org/entity/Q55433'), ('name', 'Michelangelo Antonioni'), ('prize', 'http://www.wikidata.org/entity/Q599434'), ('pname', 'Feltrinelli Prize')]
# [('person', 'http://www.wikidata.org/entity/Q53009'), ('name', 'Bernardo Bertolucci'), ('prize', 'http://www.wikidata.org/entity/Q849124'), ('pname', 'Golden Globe Award for Best Screenplay')]
# [('person', 'http://www.wikidata.org/entity/Q133855'), ('name', 'Guillaume Apollinaire'), ('prize', 'http://www.wikidata.org/entity/Q3324507'), ('pname', 'Mort pour la France')]
# [('person', 'http://www.wikidata.org/entity/Q216582'), ('name', 'Filippo Tommaso Marinettiz6eztfzitryxi'), ('prize', 'http://www.wikidata.org/entity/Q1497512'), ('pname', 'Commemorative Medal of the Unity of Italy')]
# [('person', 'http://www.wikidata.org/entity/Q8243562'), ('name', 'Basilio Boggiero Spotorno'), ('prize', 'http://www.wikidata.org/entity/Q50810210'), ('pname', 'Cross of the Martyrs of Independence')]
# [('person', 'http://www.wikidata.org/entity/Q55433'), ('name', 'Michelangelo Antonioni'), ('prize', 'http://www.wikidata.org/entity/Q1700510'), ('pname', 'Golden Leopard')]
# [('person', 'http://www.wikidata.org/entity/Q55433'), ('name', 'Michelangelo Antonioni'), ('prize', 'http://www.wikidata.org/entity/Q164200'), ('pname', 'Jury Prize')]
# [('person', 'http://www.wikidata.org/entity/Q216582'), ('name', 'Filippo Tommaso Marinettiz6eztfzitryxi'), ('prize', 'http://www.wikidata.org/entity/Q1142801'), ('pname', 'Commemorative Medal for the Italo-Austrian War 1915-1918')]
# [('person', 'http://www.wikidata.org/entity/Q8243562'), ('name', 'Basilio Boggiero Spotorno'), ('prize', 'http://www.wikidata.org/entity/Q51029722'), ('pname', 'calle Basilio Boggiero')]
# [('person', 'http://www.wikidata.org/entity/Q765'), ('name', 'Dario Fo'), ('prize', 'http://www.wikidata.org/entity/Q59399608'), ('pname', 'honorary citizen of Palermo')]
# [('person', 'http://www.wikidata.org/entity/Q55433'), ('name', 'Michelangelo Antonioni'), ('prize', 'http://www.wikidata.org/entity/Q3703245'), ('pname', 'David Luchino Visconti')]
# [('person', 'http://www.wikidata.org/entity/Q216582'), ('name', 'Filippo Tommaso Marinettiz6eztfzitryxi'), ('prize', 'http://www.wikidata.org/entity/Q4974248'), ('pname', 'Bronze Medal of Military Valour')]
# [('person', 'http://www.wikidata.org/entity/Q53009'), ('name', 'Bernardo Bertolucci'), ('prize', 'http://www.wikidata.org/entity/Q77533361'), ('pname', 'European Film Academy Special Jury Award')]
# [('person', 'http://www.wikidata.org/entity/Q216582'), ('name', 'Filippo Tommaso Marinettiz6eztfzitryxi'), ('prize', 'http://www.wikidata.org/entity/Q1497500'), ('pname', 'commemorative medal of the military operation in East Africa')]
# 53

# %% [markdown]
# Final query for this task

# %%
# Get all italian potes that won nobel prize in literature
queryString = """
SELECT DISTINCT ?person ?name ?prize ?pname
WHERE {
    # ?person wdt:P106 wd:Q49757.    #occupation is 'poet'
    # ?person wdt:P172 wd:Q50001 .   #ethnic group is italian
    # ?person sc:name ?name.
    
    # ?person wdt:P166 wd:Q37922.    #BGP to specify person won a nobel prize in literature
}
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('person', 'http://www.wikidata.org/entity/Q43440'), ('name', 'Giosuè Carducci')]
# [('person', 'http://www.wikidata.org/entity/Q1403'), ('name', 'Luigi Pirandello')]
# [('person', 'http://www.wikidata.org/entity/Q765'), ('name', 'Dario Fo')]
# 3

# %% [markdown]
# # General instructions
#
# The goal of the project is to materialize a set of **exploratory workloads** over a real-world, large-scale,  open-domain KG: [WikiData](https://www.wikidata.org/wiki/Wikidata:Main_Page)
#
# An exploratory workload  is composed by a set of queries, where each query is related to the information obtained previously.
#
# An exploratory workload starts with a usually vague, open ended question, and does not assume the person issuing the workload has a clear understanding of the data contained in the target database or its structure.
#
# Remeber that:
#
# 1. All the queries must run in the python notebook
# 2. You can use classes and properties only if you find them via a SPARQL query that must be present in the notebook
# 3. You do not delete useless queries. Keep everything that is synthatically valid
#
# ```
# ?p <http://schema.org/name> ?name .
# ```
#
#     is the BGP returning a human-readable name of a property or a class in Wikidata.

# %%
## SETUP used later

from SPARQLWrapper import SPARQLWrapper, JSON


prefixString = """
##-2438c49dac-##
PREFIX wd: <http://www.wikidata.org/entity/> 
PREFIX wdt: <http://www.wikidata.org/prop/direct/> 
PREFIX sc: <http://schema.org/>
"""

# select and construct queries
def run_query(queryString,verbose = True):
    to_run = prefixString + "\n" + queryString

    sparql = SPARQLWrapper("http://a256-gc1-03.srv.aau.dk:5820/sparql")
    sparql.setTimeout(300)
    sparql.setReturnFormat(JSON)
    sparql.setQuery(to_run)

    try :
        results = sparql.query()
        json_results = results.convert()
        if len(json_results['results']['bindings'])==0:
            print("Empty")
            return []
        array = []
        for bindings in json_results['results']['bindings']:
            app =  [ (var, value['value'])  for var, value in bindings.items() ] 
            if verbose:
                print( app)
            array.append(app)
        if verbose:
            print(len(array))
        return array

    except Exception as e :
        print("The operation failed", e)
    
# ASk queries
def run_ask_query(queryString):
    to_run = prefixString + "\n" + queryString

    sparql = SPARQLWrapper("http://a256-gc1-03.srv.aau.dk:5820/sparql")
    sparql.setTimeout(300)
    sparql.setReturnFormat(JSON)
    sparql.setQuery(to_run)

    try :
        return sparql.query().convert()

    except Exception as e :
        print("The operation failed", e)

# %% [markdown]
# # History Workflow Series ("Literary Movements and physicists explorative search")
#
# Consider the following exploratory information need:
#
# > investigate the literary movements and the poets. In particular, compare some physicists in terms of discovers, Nobel Prizes and education.

# %% [markdown]
# ## Useful URIs for the current workflow
# The following are given:
#
# | IRI           | Description   | Role      |
# | -----------   | -----------   |-----------|
# | `wdt:P1647`   | subproperty   | predicate |
# | `wdt:P31`     | instance of   | predicate |
# | `wdt:P106`    | occupation    | predicate |
# | `wdt:P279`    | subclass      | predicate |
# | `wdt:P27`     | nationality   | predicate |
# | `wdt:P3342`     | Significant person       | predicate |
# | `wd:Q5`| Human       | node |
# | `wd:Q43514`| theory of relativity | node |

# %% [markdown]
# Also consider
#
# ```
# wd:Q43514 ?p ?obj .
# ```
#
# is the BGP to retrieve all **properties of the theory of relativity**
#
# Please consider that when you return a resource, you should return the IRI and the label of the resource. In particular, when the task require you to identify a BGP the result set must always be a list of couples IRI - label.
#
# The workload should:
#
# 1. Who invented the theory of relativity? (return the IRI and the label of the inventor).
#
# 2. Identify the BGP for physicist
#
# 3. Identify the BGP for Nobel Prize
#
# 4. Consider physicists born in Europe. For each european country return the number of physicists who won the Nobel Prize in Physics (the result set must be a list of triples country IRI, label and #physicists).
#
# 5. Return the countries which won at least once all the type of Nobel Prizes with the people born there. (the result set must be a list of couples country IRI and label).
#
# 6. Amongst the physicists who won the Nobel Prize in Physics, find who had discovered or invented at least 3 things (the result set must be a list of triples physicist IRI, label and #discoveries ).
#
# 7. Amongst the physicists who won the Nobel Prize in Physics, find who taught in the university of his/her city of birth (the result set must be a list of elements of the form physicist IRI, label, university IRI and label).

# %% [markdown]
# ## Task 1
# Who invented the theory of relativity? (return the IRI and the label of the inventor).

# %%
# query example
queryString = """
SELECT DISTINCT ?p ?name
WHERE {
   # bind something
   wd:Q43514 ?p ?obj .
   # get the label
   # ?p sc:name ?name.
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P1036'), ('name', 'Dewey Decimal Classification')]
# [('p', 'http://www.wikidata.org/prop/direct/P1051'), ('name', 'PSH ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1256'), ('name', 'Iconclass notation')]
# [('p', 'http://www.wikidata.org/prop/direct/P1417'), ('name', 'Encyclopædia Britannica Online ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1424'), ('name', "topic's main template")]
# [('p', 'http://www.wikidata.org/prop/direct/P1552'), ('name', 'has quality')]
# [('p', 'http://www.wikidata.org/prop/direct/P18'), ('name', 'image')]
# [('p', 'http://www.wikidata.org/prop/direct/P227'), ('name', 'GND ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P244'), ('name', 'Library of Congress authority ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2581'), ('name', 'BabelNet ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P268'), ('name', 'Bibliothèque nationale de France ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('name', 'subclass of')]
# [('p', 'http://www.wikidata.org/prop/direct/P2924'), ('name', 'Great Russian Encyclopedia Online ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('name', 'instance of')]
# [('p', 'http://www.wikidata.org/prop/direct/P3219'), ('name', 'Encyclopædia Universalis ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3417'), ('name', 'Quora topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P349'), ('name', 'National Diet Library ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3553'), ('name', 'Zhihu topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3569'), ('name', 'Cultureel Woordenboek ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P361'), ('name', 'part of')]
# [('p', 'http://www.wikidata.org/prop/direct/P373'), ('name', 'Commons category')]
# [('p', 'http://www.wikidata.org/prop/direct/P3847'), ('name', 'Open Library subject ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3916'), ('name', 'UNESCO Thesaurus ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P4466'), ('name', 'Unified Astronomy Thesaurus ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P4613'), ('name', 'Encyclopedia of Modern Ukraine ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P508'), ('name', 'BNCF Thesaurus ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('name', 'has part')]
# [('p', 'http://www.wikidata.org/prop/direct/P5357'), ('name', 'The Encyclopedia of Science Fiction ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P61'), ('name', 'discoverer or inventor')]
# [('p', 'http://www.wikidata.org/prop/direct/P6363'), ('name', 'WordLift URL')]
# [('p', 'http://www.wikidata.org/prop/direct/P6366'), ('name', 'Microsoft Academic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P646'), ('name', 'Freebase ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6573'), ('name', 'Klexikon article ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7305'), ('name', 'Online PWN Encyclopedia ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7993'), ('name', "Treccani's Dizionario di Filosofia ID")]
# [('p', 'http://www.wikidata.org/prop/direct/P8408'), ('name', 'KBpedia ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P910'), ('name', "topic's main category")]
# [('p', 'http://www.wikidata.org/prop/direct/P989'), ('name', 'spoken text audio')]
# 38

# %%
# checking properties of the given node to find a clue
queryString = """
SELECT DISTINCT ?p ?name ?obj ?objName
WHERE {
   # bind something
   wd:Q43514 ?p ?obj .
   # get the label
   # ?p sc:name ?name.
   # ?obj sc:name ?objName
}
LIMIT 20
"""
print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('name', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q11452'), ('objName', 'general relativity')]
# [('p', 'http://www.wikidata.org/prop/direct/P361'), ('name', 'part of'), ('obj', 'http://www.wikidata.org/entity/Q658544'), ('objName', 'modern physics')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('name', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q214070'), ('objName', 'physical law')]
# [('p', 'http://www.wikidata.org/prop/direct/P1552'), ('name', 'has quality'), ('obj', 'http://www.wikidata.org/entity/Q35875'), ('objName', 'mass–energy equivalence')]
# [('p', 'http://www.wikidata.org/prop/direct/P61'), ('name', 'discoverer or inventor'), ('obj', 'http://www.wikidata.org/entity/Q937'), ('objName', 'Albert Einstein')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('name', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q11455'), ('objName', 'special relativity')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('name', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q3239681'), ('objName', 'scientific theory')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('name', 'subclass of'), ('obj', 'http://www.wikidata.org/entity/Q3239681'), ('objName', 'scientific theory')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('name', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q4162444'), ('objName', 'branch of physics')]
# [('p', 'http://www.wikidata.org/prop/direct/P910'), ('name', "topic's main category"), ('obj', 'http://www.wikidata.org/entity/Q6617097'), ('objName', 'Category:Theory of relativity')]
# [('p', 'http://www.wikidata.org/prop/direct/P1424'), ('name', "topic's main template"), ('obj', 'http://www.wikidata.org/entity/Q14839046'), ('objName', 'Template:Relativity')]
# 11

# %% [markdown]
# Final query for this task

# %%
#[('p', 'http://www.wikidata.org/prop/direct/P61'), ('name', 'discoverer or inventor'), 
#('obj', 'http://www.wikidata.org/entity/Q937'), ('objName', 'Albert Einstein')]
#FINAL 
queryString = """
SELECT DISTINCT ?inv ?invName
WHERE {
   # bind something
   wd:Q43514 ?p ?obj .
   # ?obj wdt:P61 ?inv.
   # get the label
   # ?inv sc:name ?invName
}
LIMIT 20
"""
print("Results")
x=run_query(queryString)
# Out:
# Results
# [('inv', 'http://www.wikidata.org/entity/Q937'), ('invName', 'Albert Einstein')]
# 1

# %% [markdown]
# ## Task 2
# Identify the BGP for physicist

# %%
#USING THE NODE WE FOUND FOR FINDING THE RESULTS 
#[('inv', 'http://www.wikidata.org/entity/Q937'), ('invName', 'Albert Einstein')]
#[('p', 'http://www.wikidata.org/prop/direct/P61'), ('name', 'discoverer or inventor'), 

queryString = """
SELECT DISTINCT ?inv ?invName
WHERE {
   # bind something
   wd:Q43514 ?p ?obj .
   # ?obj wdt:P61 ?inv.
   # get the label
   # ?inv sc:name ?invName
}
LIMIT 20
"""
print("Results")
x=run_query(queryString)
# Out:
# Results
# [('inv', 'http://www.wikidata.org/entity/Q937'), ('invName', 'Albert Einstein')]
# 1

# %%
#USING THE NODE WE FOUND FOR FINDING THE RESULTS 
#[('inv', 'http://www.wikidata.org/entity/Q937'), ('invName', 'Albert Einstein')]
#[('p', 'http://www.wikidata.org/prop/direct/P61'), ('name', 'discoverer or inventor'), 
#wdt:P106	occupation	predicate

queryString = """
SELECT DISTINCT ?job ?jobname
WHERE {
   # bind something
   wd:Q43514 ?p ?obj .
   # ?obj wdt:P61 ?inv.
   # ?inv wdt:P106 ?job.
   # get the label
   # ?job sc:name ?jobname
}
LIMIT 20
"""
print("Results")
x=run_query(queryString)
# Out:
# Results
# [('job', 'http://www.wikidata.org/entity/Q19350898'), ('jobname', 'theoretical physicist')]
# [('job', 'http://www.wikidata.org/entity/Q16389557'), ('jobname', 'philosopher of science')]
# [('job', 'http://www.wikidata.org/entity/Q121594'), ('jobname', 'professor')]
# [('job', 'http://www.wikidata.org/entity/Q1231865'), ('jobname', 'pedagogue')]
# [('job', 'http://www.wikidata.org/entity/Q15980158'), ('jobname', 'non-fiction writer')]
# [('job', 'http://www.wikidata.org/entity/Q1622272'), ('jobname', 'university teacher')]
# [('job', 'http://www.wikidata.org/entity/Q169470'), ('jobname', 'physicist')]
# [('job', 'http://www.wikidata.org/entity/Q170790'), ('jobname', 'mathematician')]
# [('job', 'http://www.wikidata.org/entity/Q205375'), ('jobname', 'inventor')]
# [('job', 'http://www.wikidata.org/entity/Q36180'), ('jobname', 'writer')]
# [('job', 'http://www.wikidata.org/entity/Q37226'), ('jobname', 'teacher')]
# [('job', 'http://www.wikidata.org/entity/Q4964182'), ('jobname', 'philosopher')]
# [('job', 'http://www.wikidata.org/entity/Q901'), ('jobname', 'scientist')]
# [('job', 'http://www.wikidata.org/entity/Q3745071'), ('jobname', 'science writer')]
# [('job', 'http://www.wikidata.org/entity/Q2896489'), ('jobname', 'patent examiner')]
# 15

# %% [markdown]
# Final query for this task

# %%
#USING THE NODE WE FOUND FOR FINDING THE RESULTS 
#[('inv', 'http://www.wikidata.org/entity/Q937'), ('invName', 'Albert Einstein')]
#[('p', 'http://www.wikidata.org/prop/direct/P61'), ('name', 'discoverer or inventor'), 
#wdt:P106	occupation	predicate

queryString = """
SELECT DISTINCT ?job ?jobname
WHERE {
   # bind something
   wd:Q43514 ?p ?obj .
   # ?obj wdt:P61 ?inv.
   # ?inv wdt:P106 ?job.
   # get the label
   # ?job sc:name ?jobname
   FILTER(REGEX(?jobname ,'physicist'))
}
LIMIT 20
"""
print("Results")
x=run_query(queryString)
# Out:
# Results
# [('job', 'http://www.wikidata.org/entity/Q19350898'), ('jobname', 'theoretical physicist')]
# [('job', 'http://www.wikidata.org/entity/Q169470'), ('jobname', 'physicist')]
# 2

# %% [markdown]
# ## Task 3
# Identify the BGP for Nobel Prize

# %%
queryString = """
SELECT DISTINCT ?inv ?invName
WHERE {
   # bind something
   wd:Q43514 ?p ?obj .
   # ?obj wdt:P61 ?inv.
   # get the label
   # ?inv sc:name ?invName
}
LIMIT 20
"""
print("Results")
x=run_query(queryString)
# Out:
# Results
# [('inv', 'http://www.wikidata.org/entity/Q937'), ('invName', 'Albert Einstein')]
# 1

# %%
#[('inv', 'http://www.wikidata.org/entity/Q937'), ('invName', 'Albert Einstein')]
#check properties to find the awards
queryString = """
SELECT DISTINCT ?p ?pName ?obj ?objName 
WHERE {
   # bind something
   wd:Q937 ?p ?obj .
   # get the label
   # ?p sc:name ?pName .
   # ?obj sc:name ?objName.
}
LIMIT 20
"""
print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P551'), ('pName', 'residence'), ('obj', 'http://www.wikidata.org/entity/Q1309294'), ('objName', 'Einsteinhaus Caputh')]
# [('p', 'http://www.wikidata.org/prop/direct/P800'), ('pName', 'notable work'), ('obj', 'http://www.wikidata.org/entity/Q11452'), ('objName', 'general relativity')]
# [('p', 'http://www.wikidata.org/prop/direct/P800'), ('pName', 'notable work'), ('obj', 'http://www.wikidata.org/entity/Q944'), ('objName', 'quantum mechanics')]
# [('p', 'http://www.wikidata.org/prop/direct/P69'), ('pName', 'educated at'), ('obj', 'http://www.wikidata.org/entity/Q435651'), ('objName', 'old Kantonsschule (Albert Einstein House)')]
# [('p', 'http://www.wikidata.org/prop/direct/P5021'), ('pName', 'assessment'), ('obj', 'http://www.wikidata.org/entity/Q1051792'), ('objName', 'intelligence test')]
# [('p', 'http://www.wikidata.org/prop/direct/P20'), ('pName', 'place of death'), ('obj', 'http://www.wikidata.org/entity/Q138518'), ('objName', 'Princeton')]
# [('p', 'http://www.wikidata.org/prop/direct/P551'), ('pName', 'residence'), ('obj', 'http://www.wikidata.org/entity/Q138518'), ('objName', 'Princeton')]
# [('p', 'http://www.wikidata.org/prop/direct/P937'), ('pName', 'work location'), ('obj', 'http://www.wikidata.org/entity/Q138518'), ('objName', 'Princeton')]
# [('p', 'http://www.wikidata.org/prop/direct/P166'), ('pName', 'award received'), ('obj', 'http://www.wikidata.org/entity/Q1522873'), ('objName', 'Josiah Willard Gibbs Lectureship')]
# [('p', 'http://www.wikidata.org/prop/direct/P101'), ('pName', 'field of work'), ('obj', 'http://www.wikidata.org/entity/Q18362'), ('objName', 'theoretical physics')]
# [('p', 'http://www.wikidata.org/prop/direct/P69'), ('pName', 'educated at'), ('obj', 'http://www.wikidata.org/entity/Q1876751'), ('objName', 'Luitpold-Gymnasium')]
# [('p', 'http://www.wikidata.org/prop/direct/P106'), ('pName', 'occupation'), ('obj', 'http://www.wikidata.org/entity/Q19350898'), ('objName', 'theoretical physicist')]
# [('p', 'http://www.wikidata.org/prop/direct/P166'), ('pName', 'award received'), ('obj', 'http://www.wikidata.org/entity/Q317038'), ('objName', 'Max Planck Medal')]
# [('p', 'http://www.wikidata.org/prop/direct/P102'), ('pName', 'member of political party'), ('obj', 'http://www.wikidata.org/entity/Q328195'), ('objName', 'German Democratic Party')]
# [('p', 'http://www.wikidata.org/prop/direct/P735'), ('pName', 'given name'), ('obj', 'http://www.wikidata.org/entity/Q577011'), ('objName', 'Albert')]
# [('p', 'http://www.wikidata.org/prop/direct/P108'), ('pName', 'employer'), ('obj', 'http://www.wikidata.org/entity/Q659080'), ('objName', 'University of Bern')]
# [('p', 'http://www.wikidata.org/prop/direct/P108'), ('pName', 'employer'), ('obj', 'http://www.wikidata.org/entity/Q708038'), ('objName', 'Kaiser Wilhelm Society')]
# [('p', 'http://www.wikidata.org/prop/direct/P937'), ('pName', 'work location'), ('obj', 'http://www.wikidata.org/entity/Q72'), ('objName', 'Zürich')]
# [('p', 'http://www.wikidata.org/prop/direct/P1321'), ('pName', 'place of origin (Switzerland)'), ('obj', 'http://www.wikidata.org/entity/Q72'), ('objName', 'Zürich')]
# [('p', 'http://www.wikidata.org/prop/direct/P106'), ('pName', 'occupation'), ('obj', 'http://www.wikidata.org/entity/Q16389557'), ('objName', 'philosopher of science')]
# 20

# %%
#[('inv', 'http://www.wikidata.org/entity/Q937'), ('invName', 'Albert Einstein')]
#[('p', 'http://www.wikidata.org/prop/direct/P166'), ('pName', 'award received'),

#check awards  to find the nobel prize 

queryString = """
SELECT DISTINCT  ?award ?awardName
WHERE {
   # bind something
   wd:Q937 ?p ?obj ;
       wdt:P166 ?award .
   # get the label
  # ?award sc:name ?awardName.
  FILTER(REGEX(?awardName ,'[Nn]obel'))
}
LIMIT 20
"""
print("Results")
x=run_query(queryString)
# Out:
# Results
# [('award', 'http://www.wikidata.org/entity/Q38104'), ('awardName', 'Nobel Prize in Physics')]
# 1

# %% [markdown]
# Final query for this task

# %%
#[('award', 'http://www.wikidata.org/entity/Q38104'), ('awardName', 'Nobel Prize in Physics')]
#wdt:P279	subclass	predicate
#FINAL QUERY 
queryString = """
SELECT DISTINCT ?obj ?objName
WHERE {
   # bind something
    wd:Q38104 wdt:P279 ?obj.
    
   # get the label
    
   # ?obj sc:name ?objName.
  
}
LIMIT 20
"""
print("Results")
x=run_query(queryString)
# Out:
# Results
# [('obj', 'http://www.wikidata.org/entity/Q7191'), ('objName', 'Nobel Prize')]
# 1

# %% [markdown]
# ## Task 4
# Consider physicists born in Europe. For each european country return the number of physicists who won the Nobel Prize in Physics (the result set must be a list of triples country IRI, label and #physicists).

# %%
#STARTING FROM A FOUND NODE TO FIND THE BIRTH COUNTRY PROPERTY 
queryString = """
SELECT DISTINCT ?inv ?invName
WHERE {
   # bind something
   wd:Q43514 ?p ?obj .
   # ?obj wdt:P61 ?inv.
   # get the label
   # ?inv sc:name ?invName
}
LIMIT 200
"""
print("Results")
x=run_query(queryString)
# Out:
# Results
# [('inv', 'http://www.wikidata.org/entity/Q937'), ('invName', 'Albert Einstein')]
# 1

# %%
#[('inv', 'http://www.wikidata.org/entity/Q937'), ('invName', 'Albert Einstein')]
queryString = """
SELECT DISTINCT ?p ?pname ?inv ?invName
WHERE {
   # bind something
   wd:Q937 ?p ?obj .
   # ?obj wdt:P31 ?inv.
   # get the label
   # ?p sc:name ?pname.
   # ?inv sc:name ?invName
}
LIMIT 70
"""
print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P551'), ('pname', 'residence'), ('inv', 'http://www.wikidata.org/entity/Q279118'), ('invName', 'wooden house')]
# [('p', 'http://www.wikidata.org/prop/direct/P27'), ('pname', 'country of citizenship'), ('inv', 'http://www.wikidata.org/entity/Q1489259'), ('invName', 'superpower')]
# [('p', 'http://www.wikidata.org/prop/direct/P937'), ('pname', 'work location'), ('inv', 'http://www.wikidata.org/entity/Q257391'), ('invName', 'federal capital')]
# [('p', 'http://www.wikidata.org/prop/direct/P106'), ('pname', 'occupation'), ('inv', 'http://www.wikidata.org/entity/Q5767753'), ('invName', 'style')]
# [('p', 'http://www.wikidata.org/prop/direct/P39'), ('pname', 'position held'), ('inv', 'http://www.wikidata.org/entity/Q5767753'), ('invName', 'style')]
# [('p', 'http://www.wikidata.org/prop/direct/P803'), ('pname', 'professorship'), ('inv', 'http://www.wikidata.org/entity/Q5767753'), ('invName', 'style')]
# [('p', 'http://www.wikidata.org/prop/direct/P106'), ('pname', 'occupation'), ('inv', 'http://www.wikidata.org/entity/Q7810129'), ('invName', 'title of authority')]
# [('p', 'http://www.wikidata.org/prop/direct/P39'), ('pname', 'position held'), ('inv', 'http://www.wikidata.org/entity/Q7810129'), ('invName', 'title of authority')]
# [('p', 'http://www.wikidata.org/prop/direct/P803'), ('pname', 'professorship'), ('inv', 'http://www.wikidata.org/entity/Q7810129'), ('invName', 'title of authority')]
# [('p', 'http://www.wikidata.org/prop/direct/P485'), ('pname', 'archives at'), ('inv', 'http://www.wikidata.org/entity/Q1865249'), ('invName', 'literary museum')]
# [('p', 'http://www.wikidata.org/prop/direct/P5008'), ('pname', 'on focus list of Wikimedia project'), ('inv', 'http://www.wikidata.org/entity/Q16695773'), ('invName', 'WikiProject')]
# [('p', 'http://www.wikidata.org/prop/direct/P108'), ('pname', 'employer'), ('inv', 'http://www.wikidata.org/entity/Q15911314'), ('invName', 'association')]
# [('p', 'http://www.wikidata.org/prop/direct/P485'), ('pname', 'archives at'), ('inv', 'http://www.wikidata.org/entity/Q166118'), ('invName', 'archive')]
# [('p', 'http://www.wikidata.org/prop/direct/P108'), ('pname', 'employer'), ('inv', 'http://www.wikidata.org/entity/Q166118'), ('invName', 'archive')]
# [('p', 'http://www.wikidata.org/prop/direct/P1344'), ('pname', 'participant in'), ('inv', 'http://www.wikidata.org/entity/Q170584'), ('invName', 'project')]
# [('p', 'http://www.wikidata.org/prop/direct/P108'), ('pname', 'employer'), ('inv', 'http://www.wikidata.org/entity/Q20971972'), ('invName', 'Original Public Ivy')]
# [('p', 'http://www.wikidata.org/prop/direct/P108'), ('pname', 'employer'), ('inv', 'http://www.wikidata.org/entity/Q23002039'), ('invName', 'public educational institution of the United States')]
# [('p', 'http://www.wikidata.org/prop/direct/P119'), ('pname', 'place of burial'), ('inv', 'http://www.wikidata.org/entity/Q2772772'), ('invName', 'military museum')]
# [('p', 'http://www.wikidata.org/prop/direct/P108'), ('pname', 'employer'), ('inv', 'http://www.wikidata.org/entity/Q615150'), ('invName', 'land-grant university')]
# [('p', 'http://www.wikidata.org/prop/direct/P1343'), ('pname', 'described by source'), ('inv', 'http://www.wikidata.org/entity/Q8513'), ('invName', 'database')]
# [('p', 'http://www.wikidata.org/prop/direct/P463'), ('pname', 'member of'), ('inv', 'http://www.wikidata.org/entity/Q1320047'), ('invName', 'book publisher')]
# [('p', 'http://www.wikidata.org/prop/direct/P463'), ('pname', 'member of'), ('inv', 'http://www.wikidata.org/entity/Q2085381'), ('invName', 'publisher')]
# [('p', 'http://www.wikidata.org/prop/direct/P1343'), ('pname', 'described by source'), ('inv', 'http://www.wikidata.org/entity/Q186165'), ('invName', 'web portal')]
# [('p', 'http://www.wikidata.org/prop/direct/P27'), ('pname', 'country of citizenship'), ('inv', 'http://www.wikidata.org/entity/Q19953632'), ('invName', 'former administrative territorial entity')]
# [('p', 'http://www.wikidata.org/prop/direct/P800'), ('pname', 'notable work'), ('inv', 'http://www.wikidata.org/entity/Q211364'), ('invName', 'principle')]
# [('p', 'http://www.wikidata.org/prop/direct/P166'), ('pname', 'award received'), ('inv', 'http://www.wikidata.org/entity/Q618779'), ('invName', 'award')]
# [('p', 'http://www.wikidata.org/prop/direct/P108'), ('pname', 'employer'), ('inv', 'http://www.wikidata.org/entity/Q748019'), ('invName', 'scientific society')]
# [('p', 'http://www.wikidata.org/prop/direct/P803'), ('pname', 'professorship'), ('inv', 'http://www.wikidata.org/entity/Q216353'), ('invName', 'title')]
# [('p', 'http://www.wikidata.org/prop/direct/P485'), ('pname', 'archives at'), ('inv', 'http://www.wikidata.org/entity/Q4431094'), ('invName', 'special collections')]
# [('p', 'http://www.wikidata.org/prop/direct/P551'), ('pname', 'residence'), ('inv', 'http://www.wikidata.org/entity/Q5003624'), ('invName', 'memorial')]
# [('p', 'http://www.wikidata.org/prop/direct/P937'), ('pname', 'work location'), ('inv', 'http://www.wikidata.org/entity/Q548611'), ('invName', 'districts of the Czech Republic')]
# [('p', 'http://www.wikidata.org/prop/direct/P27'), ('pname', 'country of citizenship'), ('inv', 'http://www.wikidata.org/entity/Q99541706'), ('invName', 'historical unrecognized state')]
# [('p', 'http://www.wikidata.org/prop/direct/P551'), ('pname', 'residence'), ('inv', 'http://www.wikidata.org/entity/Q1066984'), ('invName', 'financial centre')]
# [('p', 'http://www.wikidata.org/prop/direct/P463'), ('pname', 'member of'), ('inv', 'http://www.wikidata.org/entity/Q12020836'), ('invName', 'timber-framed house')]
# [('p', 'http://www.wikidata.org/prop/direct/P800'), ('pname', 'notable work'), ('inv', 'http://www.wikidata.org/entity/Q173227'), ('invName', 'physical constant')]
# [('p', 'http://www.wikidata.org/prop/direct/P463'), ('pname', 'member of'), ('inv', 'http://www.wikidata.org/entity/Q1966910'), ('invName', 'national academy')]
# [('p', 'http://www.wikidata.org/prop/direct/P2959'), ('pname', 'permanent duplicated item'), ('inv', 'http://www.wikidata.org/entity/Q21286738'), ('invName', 'Wikimedia permanent duplicate item')]
# [('p', 'http://www.wikidata.org/prop/direct/P463'), ('pname', 'member of'), ('inv', 'http://www.wikidata.org/entity/Q414147'), ('invName', 'academy of sciences')]
# [('p', 'http://www.wikidata.org/prop/direct/P108'), ('pname', 'employer'), ('inv', 'http://www.wikidata.org/entity/Q414147'), ('invName', 'academy of sciences')]
# [('p', 'http://www.wikidata.org/prop/direct/P485'), ('pname', 'archives at'), ('inv', 'http://www.wikidata.org/entity/Q1497649'), ('invName', 'memory institution')]
# [('p', 'http://www.wikidata.org/prop/direct/P1343'), ('pname', 'described by source'), ('inv', 'http://www.wikidata.org/entity/Q1789476'), ('invName', 'bibliographic database')]
# [('p', 'http://www.wikidata.org/prop/direct/P108'), ('pname', 'employer'), ('inv', 'http://www.wikidata.org/entity/Q1371037'), ('invName', 'institute of technology')]
# [('p', 'http://www.wikidata.org/prop/direct/P69'), ('pname', 'educated at'), ('inv', 'http://www.wikidata.org/entity/Q1371037'), ('invName', 'institute of technology')]
# [('p', 'http://www.wikidata.org/prop/direct/P21'), ('pname', 'sex or gender'), ('inv', 'http://www.wikidata.org/entity/Q48264'), ('invName', 'gender identity')]
# [('p', 'http://www.wikidata.org/prop/direct/P485'), ('pname', 'archives at'), ('inv', 'http://www.wikidata.org/entity/Q856234'), ('invName', 'academic library')]
# [('p', 'http://www.wikidata.org/prop/direct/P172'), ('pname', 'ethnic group'), ('inv', 'http://www.wikidata.org/entity/Q11197007'), ('invName', 'ethnoreligious group')]
# [('p', 'http://www.wikidata.org/prop/direct/P1441'), ('pname', 'present in work'), ('inv', 'http://www.wikidata.org/entity/Q11424'), ('invName', 'film')]
# [('p', 'http://www.wikidata.org/prop/direct/P27'), ('pname', 'country of citizenship'), ('inv', 'http://www.wikidata.org/entity/Q11514315'), ('invName', 'historical period')]
# [('p', 'http://www.wikidata.org/prop/direct/P1424'), ('pname', "topic's main template"), ('inv', 'http://www.wikidata.org/entity/Q11753321'), ('invName', 'Wikimedia navigational template')]
# [('p', 'http://www.wikidata.org/prop/direct/P551'), ('pname', 'residence'), ('inv', 'http://www.wikidata.org/entity/Q1180262'), ('invName', 'residenz')]
# [('p', 'http://www.wikidata.org/prop/direct/P937'), ('pname', 'work location'), ('inv', 'http://www.wikidata.org/entity/Q1187811'), ('invName', 'college town')]
# [('p', 'http://www.wikidata.org/prop/direct/P1321'), ('pname', 'place of origin (Switzerland)'), ('inv', 'http://www.wikidata.org/entity/Q1187811'), ('invName', 'college town')]
# [('p', 'http://www.wikidata.org/prop/direct/P551'), ('pname', 'residence'), ('inv', 'http://www.wikidata.org/entity/Q1187811'), ('invName', 'college town')]
# [('p', 'http://www.wikidata.org/prop/direct/P19'), ('pname', 'place of birth'), ('inv', 'http://www.wikidata.org/entity/Q1187811'), ('invName', 'college town')]
# [('p', 'http://www.wikidata.org/prop/direct/P108'), ('pname', 'employer'), ('inv', 'http://www.wikidata.org/entity/Q1187811'), ('invName', 'college town')]
# [('p', 'http://www.wikidata.org/prop/direct/P937'), ('pname', 'work location'), ('inv', 'http://www.wikidata.org/entity/Q1221156'), ('invName', 'state of Germany')]
# [('p', 'http://www.wikidata.org/prop/direct/P106'), ('pname', 'occupation'), ('inv', 'http://www.wikidata.org/entity/Q12737077'), ('invName', 'occupation')]
# [('p', 'http://www.wikidata.org/prop/direct/P1412'), ('pname', 'languages spoken, written or signed'), ('inv', 'http://www.wikidata.org/entity/Q1288568'), ('invName', 'modern language')]
# [('p', 'http://www.wikidata.org/prop/direct/P6886'), ('pname', 'writing language'), ('inv', 'http://www.wikidata.org/entity/Q1288568'), ('invName', 'modern language')]
# [('p', 'http://www.wikidata.org/prop/direct/P103'), ('pname', 'native language'), ('inv', 'http://www.wikidata.org/entity/Q1288568'), ('invName', 'modern language')]
# [('p', 'http://www.wikidata.org/prop/direct/P800'), ('pname', 'notable work'), ('inv', 'http://www.wikidata.org/entity/Q1293220'), ('invName', 'physical phenomenon')]
# [('p', 'http://www.wikidata.org/prop/direct/P5008'), ('pname', 'on focus list of Wikimedia project'), ('inv', 'http://www.wikidata.org/entity/Q13406463'), ('invName', 'Wikimedia list article')]
# [('p', 'http://www.wikidata.org/prop/direct/P551'), ('pname', 'residence'), ('inv', 'http://www.wikidata.org/entity/Q134626'), ('invName', 'district capital')]
# [('p', 'http://www.wikidata.org/prop/direct/P19'), ('pname', 'place of birth'), ('inv', 'http://www.wikidata.org/entity/Q134626'), ('invName', 'district capital')]
# [('p', 'http://www.wikidata.org/prop/direct/P140'), ('pname', 'religion'), ('inv', 'http://www.wikidata.org/entity/Q13649246'), ('invName', 'uncertainty')]
# [('p', 'http://www.wikidata.org/prop/direct/P937'), ('pname', 'work location'), ('inv', 'http://www.wikidata.org/entity/Q14770218'), ('invName', 'cantonal capital of Switzerland')]
# [('p', 'http://www.wikidata.org/prop/direct/P1321'), ('pname', 'place of origin (Switzerland)'), ('inv', 'http://www.wikidata.org/entity/Q14770218'), ('invName', 'cantonal capital of Switzerland')]
# [('p', 'http://www.wikidata.org/prop/direct/P108'), ('pname', 'employer'), ('inv', 'http://www.wikidata.org/entity/Q14770218'), ('invName', 'cantonal capital of Switzerland')]
# [('p', 'http://www.wikidata.org/prop/direct/P551'), ('pname', 'residence'), ('inv', 'http://www.wikidata.org/entity/Q14784328'), ('invName', 'state capital in Germany')]
# [('p', 'http://www.wikidata.org/prop/direct/P800'), ('pname', 'notable work'), ('inv', 'http://www.wikidata.org/entity/Q151885'), ('invName', 'concept')]
# 70

# %%
#[('p', 'http://www.wikidata.org/prop/direct/P19'), ('pname', 'place of birth'), 3
#USING THE PLACE OF BIRTH TO FIND THE COUNTRY BY CHECKING IT'S PROPERTIES 
queryString = """
SELECT DISTINCT ?p ?pname 
WHERE {
   # bind something
   wd:Q937 wdt:P19 ?x.
   # ?x ?p ?inv.

   # get the label
   # ?p sc:name ?pname.
   FILTER(REGEX(?pname ,'country'))

 
}
LIMIT 100
"""
print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P17'), ('pname', 'country')]
# 1

# %%
#[('p', 'http://www.wikidata.org/prop/direct/P17'), ('pname', 'country')]
 
queryString = """
SELECT DISTINCT ?inv ?invName
WHERE {
   # bind something
   wd:Q937 wdt:P19 ?x.
   # ?x wdt:P17 ?inv.

   # get the label
   #?n sc:name ?name.
  # ?p sc:name ?pname.
 # ?inv sc:name ?invName
}
LIMIT 100
"""
print("Results")
x=run_query(queryString)
# Out:
# Results
# [('inv', 'http://www.wikidata.org/entity/Q183'), ('invName', 'Germany')]
# 1

# %%
#[('p', 'http://www.wikidata.org/prop/direct/P17'), ('pname', 'country')]
#CHECKING THE COUNTRY PRIPERTIES TO FIND THW CONTINENT 
queryString = """
SELECT DISTINCT ?p ?pname
WHERE {
   # bind something
   wd:Q937 wdt:P19 ?x.
   # ?x wdt:P17 ?inv.
   # ?inv ?p ?n .

   # get the label
   # ?n sc:name ?name.
   # ?p sc:name ?pname.
   FILTER(REGEX(?pname ,'continent'))
}
LIMIT 100
"""
print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P30'), ('pname', 'continent')]
# 1

# %%
#[('p', 'http://www.wikidata.org/prop/direct/P30'), ('pname', 'continent')]
#AS THE ANES Albert Einstein IS EUROPEAN CHECK THE CONTINENT OF HIS BIRTH PLACE 
queryString = """
SELECT DISTINCT ?n ?name
WHERE {
   # bind something
   wd:Q937 wdt:P19 ?x.
   # ?x wdt:P17 ?inv.
   # ?inv wdt:P30 ?n .

   # get the label
   # ?n sc:name ?name.
   #?p sc:name ?pname.
# ?inv sc:name ?invName
}
LIMIT 100
"""
print("Results")
x=run_query(queryString)
# Out:
# Results
# [('n', 'http://www.wikidata.org/entity/Q46'), ('name', 'Europe')]
# 1

# %%
#[('n', 'http://www.wikidata.org/entity/Q46'), ('name', 'Europe')]
#[('job', 'http://www.wikidata.org/entity/Q169470'), ('jobname', 'physicist')]
#[('p', 'http://www.wikidata.org/prop/direct/P30'), ('pname', 'continent')]
#[('p', 'http://www.wikidata.org/prop/direct/P17'), ('pname', 'country')]
#[('p', 'http://www.wikidata.org/prop/direct/P19'), ('pname', 'place of birth'), 3
#wdt:P106	occupation	predicate
#FINDING EUROPEANS
queryString = """
SELECT DISTINCT   ?person  ?personName
WHERE {
    #being european 
    # ?person wdt:P19 ?birthplace.
    # ?birthplace wdt:P17 ?countryofbirth.
    # ?countryofbirth wdt:P30 wd:Q46.
    
    
    
    
    # ?person sc:name ?personName.
   
}

LIMIT 10
"""
print("Results")
x=run_query(queryString)
# Out:
# Results
# [('person', 'http://www.wikidata.org/entity/Q15869777'), ('personName', 'Alice Pirard')]
# [('person', 'http://www.wikidata.org/entity/Q15918318'), ('personName', 'Philippe Henri Coclers van Wyck')]
# [('person', 'http://www.wikidata.org/entity/Q4276453'), ('personName', 'Petr Makushin')]
# [('person', 'http://www.wikidata.org/entity/Q8187363'), ('personName', 'Andreĭ Ivanovich Borisov')]
# [('person', 'http://www.wikidata.org/entity/Q16145198'), ('personName', 'Philippe Grandjean')]
# [('person', 'http://www.wikidata.org/entity/Q456662'), ('personName', 'Nabiha')]
# [('person', 'http://www.wikidata.org/entity/Q8706868'), ('personName', 'Christian Rantzau')]
# [('person', 'http://www.wikidata.org/entity/Q15731855'), ('personName', 'Gustav Holck-Winterfeldt')]
# [('person', 'http://www.wikidata.org/entity/Q13646019'), ('personName', 'Mladen')]
# [('person', 'http://www.wikidata.org/entity/Q15734007'), ('personName', 'Kadri Prishtina')]
# 10

# %%
#[('n', 'http://www.wikidata.org/entity/Q46'), ('name', 'Europe')]
#[('job', 'http://www.wikidata.org/entity/Q169470'), ('jobname', 'physicist')]
#[('p', 'http://www.wikidata.org/prop/direct/P30'), ('pname', 'continent')]
#[('p', 'http://www.wikidata.org/prop/direct/P17'), ('pname', 'country')]
#[('p', 'http://www.wikidata.org/prop/direct/P19'), ('pname', 'place of birth'), 3
#[('p', 'http://www.wikidata.org/prop/direct/P166'), ('pName', 'award received'),
#[('award', 'http://www.wikidata.org/entity/Q38104'), ('awardName', 'Nobel Prize in Physics')]

#wdt:P106	occupation	predicate
#FINDING EUROPEANS WHO ARE physicist and won the nobel of pysics
queryString = """
SELECT DISTINCT   ?person  ?personName
WHERE {
    #being european 
    # ?person wdt:P19 ?birthplace.
    # ?birthplace wdt:P17 ?countryofbirth.
    # ?countryofbirth wdt:P30 wd:Q46.
    
    #being pysict
    
    # ?person wdt:P106 wd:Q169470.
    
    #winner of Nobel of pysics
    # ?person wdt:P166 wd:Q38104.
    
    
    # ?person sc:name ?personName.
 
   
}

LIMIT 10
"""
print("Results")
x=run_query(queryString)
# Out:
# Results
# [('person', 'http://www.wikidata.org/entity/Q76766'), ('personName', 'Gerd Binnig')]
# [('person', 'http://www.wikidata.org/entity/Q57072'), ('personName', 'Otto Stern')]
# [('person', 'http://www.wikidata.org/entity/Q71024'), ('personName', 'Klaus von Klitzing')]
# [('person', 'http://www.wikidata.org/entity/Q65807'), ('personName', 'Reinhard Genzel')]
# [('person', 'http://www.wikidata.org/entity/Q71022'), ('personName', 'Ernst Ruska')]
# [('person', 'http://www.wikidata.org/entity/Q71023'), ('personName', 'Alfred Kastler')]
# [('person', 'http://www.wikidata.org/entity/Q57063'), ('personName', 'Philipp Lenard')]
# [('person', 'http://www.wikidata.org/entity/Q57067'), ('personName', 'Max von Laue')]
# [('person', 'http://www.wikidata.org/entity/Q57068'), ('personName', 'Wilhelm Wien')]
# [('person', 'http://www.wikidata.org/entity/Q57070'), ('personName', 'Gustav Ludwig Hertz')]
# 10

# %% [markdown]
# Final query for this task

# %%
#[('n', 'http://www.wikidata.org/entity/Q46'), ('name', 'Europe')]
#[('job', 'http://www.wikidata.org/entity/Q169470'), ('jobname', 'physicist')]
#[('p', 'http://www.wikidata.org/prop/direct/P30'), ('pname', 'continent')]
#[('p', 'http://www.wikidata.org/prop/direct/P17'), ('pname', 'country')]

#FINAL QUERY 
queryString = """
SELECT DISTINCT    ?countryofbirth ?countryName (count(?person) as ?number )
WHERE {
    #being european 
    # ?person wdt:P19 ?birthplace.
    # ?birthplace wdt:P17 ?countryofbirth.
    # ?countryofbirth wdt:P30 wd:Q46.
    
    #being pysict
    
    # ?person wdt:P106 wd:Q169470.
    
    #winner of Nobel of pysics
    # ?person wdt:P166 wd:Q38104.
    
    
     # ?countryofbirth sc:name ?countryName .
 
   
}


"""
print("Results")
x=run_query(queryString)
# Out:
# Results
# [('countryofbirth', 'http://www.wikidata.org/entity/Q756617'), ('countryName', 'Danish Realm'), ('number', '2')]
# [('countryofbirth', 'http://www.wikidata.org/entity/Q159'), ('countryName', 'Russia'), ('number', '9')]
# [('countryofbirth', 'http://www.wikidata.org/entity/Q184'), ('countryName', 'Belarus'), ('number', '1')]
# [('countryofbirth', 'http://www.wikidata.org/entity/Q27'), ('countryName', 'Ireland'), ('number', '1')]
# [('countryofbirth', 'http://www.wikidata.org/entity/Q39'), ('countryName', 'Switzerland'), ('number', '5')]
# [('countryofbirth', 'http://www.wikidata.org/entity/Q20'), ('countryName', 'Norway'), ('number', '1')]
# [('countryofbirth', 'http://www.wikidata.org/entity/Q214'), ('countryName', 'Slovakia'), ('number', '1')]
# [('countryofbirth', 'http://www.wikidata.org/entity/Q28'), ('countryName', 'Hungary'), ('number', '2')]
# [('countryofbirth', 'http://www.wikidata.org/entity/Q227'), ('countryName', 'Azerbaijan'), ('number', '1')]
# [('countryofbirth', 'http://www.wikidata.org/entity/Q31'), ('countryName', 'Belgium'), ('number', '1')]
# [('countryofbirth', 'http://www.wikidata.org/entity/Q213'), ('countryName', 'Czech Republic'), ('number', '1')]
# [('countryofbirth', 'http://www.wikidata.org/entity/Q36'), ('countryName', 'Poland'), ('number', '7')]
# [('countryofbirth', 'http://www.wikidata.org/entity/Q40'), ('countryName', 'Austria'), ('number', '2')]
# [('countryofbirth', 'http://www.wikidata.org/entity/Q55'), ('countryName', 'Netherlands'), ('number', '9')]
# [('countryofbirth', 'http://www.wikidata.org/entity/Q32'), ('countryName', 'Luxembourg'), ('number', '1')]
# [('countryofbirth', 'http://www.wikidata.org/entity/Q38'), ('countryName', 'Italy'), ('number', '5')]
# [('countryofbirth', 'http://www.wikidata.org/entity/Q145'), ('countryName', 'United Kingdom'), ('number', '22')]
# [('countryofbirth', 'http://www.wikidata.org/entity/Q183'), ('countryName', 'Germany'), ('number', '26')]
# [('countryofbirth', 'http://www.wikidata.org/entity/Q29999'), ('countryName', 'Kingdom of the Netherlands'), ('number', '1')]
# [('countryofbirth', 'http://www.wikidata.org/entity/Q142'), ('countryName', 'France'), ('number', '9')]
# [('countryofbirth', 'http://www.wikidata.org/entity/Q212'), ('countryName', 'Ukraine'), ('number', '1')]
# [('countryofbirth', 'http://www.wikidata.org/entity/Q34'), ('countryName', 'Sweden'), ('number', '4')]
# 22

# %% [markdown]
# ## Task 5
# Return the countries which won at least once all the type of Nobel Prizes with the people born there. (the result set must be a list of couples country IRI and label).

# %%
#[('obj', 'http://www.wikidata.org/entity/Q7191'), ('objName', 'Nobel Prize')]


#finding all type of Nobel Prize
queryString = """
SELECT DISTINCT ?allNp  ?allNpname
WHERE {
    # ?allNp wdt:P279 wd:Q7191.
    # ?allNp sc:name ?allNpname.

}

"""
print("Results")
x=run_query(queryString)
# Out:
# Results
# [('allNp', 'http://www.wikidata.org/entity/Q35637'), ('allNpname', 'Nobel Peace Prize')]
# [('allNp', 'http://www.wikidata.org/entity/Q37922'), ('allNpname', 'Nobel Prize in Literature')]
# [('allNp', 'http://www.wikidata.org/entity/Q38104'), ('allNpname', 'Nobel Prize in Physics')]
# [('allNp', 'http://www.wikidata.org/entity/Q44585'), ('allNpname', 'Nobel Prize in Chemistry')]
# [('allNp', 'http://www.wikidata.org/entity/Q47170'), ('allNpname', 'Prize in Economic Sciences in Memory of Alfred Nobel')]
# [('allNp', 'http://www.wikidata.org/entity/Q80061'), ('allNpname', 'Nobel Prize in Physiology or Medicine')]
# 6

# %%
#[('obj', 'http://www.wikidata.org/entity/Q7191'), ('objName', 'Nobel Prize')]
#[('p', 'http://www.wikidata.org/prop/direct/P17'), ('pname', 'country')]
#[('p', 'http://www.wikidata.org/prop/direct/P19'), ('pname', 'place of birth')
# P19 Gives Birth PLace (Based on Previous achived results )
#P17 Gives the country of Birth Place (Based on Previous achived results)


#finding country of all people 
queryString = """
SELECT DISTINCT ?country
WHERE {
    # ?person wdt:P19 ?birthPlace.
    # ?birthPlace wdt:P17 ?country.
    
    
}

LIMIT 10
"""
print("Results")
x=run_query(queryString)
# Out:
# Results
# [('country', 'http://www.wikidata.org/entity/Q252')]
# [('country', 'http://www.wikidata.org/entity/Q191')]
# [('country', 'http://www.wikidata.org/entity/Q17')]
# [('country', 'http://www.wikidata.org/entity/Q37')]
# [('country', 'http://www.wikidata.org/entity/Q219')]
# [('country', 'http://www.wikidata.org/entity/Q29')]
# [('country', 'http://www.wikidata.org/entity/Q30')]
# [('country', 'http://www.wikidata.org/entity/Q668')]
# [('country', 'http://www.wikidata.org/entity/Q8680')]
# [('country', 'http://www.wikidata.org/entity/Q929')]
# 10

# %%
#[('p', 'http://www.wikidata.org/prop/direct/P166'), ('pName', 'award received'),
#[('obj', 'http://www.wikidata.org/entity/Q7191'), ('objName', 'Nobel Prize')]
#[('p', 'http://www.wikidata.org/prop/direct/P17'), ('pname', 'country')]
#[('p', 'http://www.wikidata.org/prop/direct/P19'), ('pname', 'place of birth')

#finding country of people who won a nobel prize 
queryString = """
SELECT DISTINCT ?country
WHERE {
    # ?person wdt:P19 ?birthPlace;
            wdt:P166 ?award .
    # ?birthPlace wdt:P17 ?country.
    # ?award  wdt:P279 wd:Q7191.
    
    
}

LIMIT 10
"""
print("Results")
x=run_query(queryString)
# Out:
# Results
# [('country', 'http://www.wikidata.org/entity/Q574')]
# [('country', 'http://www.wikidata.org/entity/Q145')]
# [('country', 'http://www.wikidata.org/entity/Q142')]
# [('country', 'http://www.wikidata.org/entity/Q30')]
# [('country', 'http://www.wikidata.org/entity/Q34')]
# [('country', 'http://www.wikidata.org/entity/Q155')]
# [('country', 'http://www.wikidata.org/entity/Q20')]
# [('country', 'http://www.wikidata.org/entity/Q760')]
# [('country', 'http://www.wikidata.org/entity/Q188712')]
# [('country', 'http://www.wikidata.org/entity/Q262')]
# 10

# %%
#[('allNp', 'http://www.wikidata.org/entity/Q35637'), ('allNpname', 'Nobel Peace Prize')]
#[('allNp', 'http://www.wikidata.org/entity/Q37922'), ('allNpname', 'Nobel Prize in Literature')]
#[('allNp', 'http://www.wikidata.org/entity/Q38104'), ('allNpname', 'Nobel Prize in Physics')]
#[('allNp', 'http://www.wikidata.org/entity/Q44585'), ('allNpname', 'Nobel Prize in Chemistry')]
#[('allNp', 'http://www.wikidata.org/entity/Q47170'), ('allNpname', 'Prize in Economic Sciences in Memory of Alfred Nobel')]
#[('allNp', 'http://www.wikidata.org/entity/Q80061'), ('allNpname', 'Nobel Prize in Physiology or Medicine')]
# VALUES ?award {Q35637 Q37922 Q38104 Q44585 Q47170 Q80061 }
queryString = """
SELECT DISTINCT  ?countrylabel  ?awardName 
WHERE {
    
    VALUES ?award {wd:Q35637 wd:Q37922 wd:Q38104 wd:Q44585 wd:Q47170 wd:Q80061}
    # ?person wdt:P19 ?birthPlace;
            wdt:P166 ?award .
    # ?birthPlace wdt:P17 ?country.
    # ?award  wdt:P279 wd:Q7191.
    # ?country sc:name ?countrylabel .
    # ?award sc:name ?awardName
    
} group by ?countrylabel 
order by ?countrylabel



LIMIT 10
"""
print("Results")
x=run_query(queryString)
# Out:
# Results
# [('countrylabel', 'Algeria'), ('awardName', 'Nobel Prize in Physics')]
# [('countrylabel', 'Algeria'), ('awardName', 'Nobel Prize in Literature')]
# [('countrylabel', 'Argentina'), ('awardName', 'Nobel Peace Prize')]
# [('countrylabel', 'Argentina'), ('awardName', 'Nobel Prize in Physiology or Medicine')]
# [('countrylabel', 'Australia'), ('awardName', 'Nobel Prize in Chemistry')]
# [('countrylabel', 'Australia'), ('awardName', 'Nobel Prize in Physics')]
# [('countrylabel', 'Australia'), ('awardName', 'Nobel Prize in Physiology or Medicine')]
# [('countrylabel', 'Austria'), ('awardName', 'Nobel Prize in Physiology or Medicine')]
# [('countrylabel', 'Austria'), ('awardName', 'Prize in Economic Sciences in Memory of Alfred Nobel')]
# [('countrylabel', 'Austria'), ('awardName', 'Nobel Peace Prize')]
# 10

# %% [markdown]
# Final query for this task

# %%
#[('allNp', 'http://www.wikidata.org/entity/Q35637'), ('allNpname', 'Nobel Peace Prize')]
#[('allNp', 'http://www.wikidata.org/entity/Q37922'), ('allNpname', 'Nobel Prize in Literature')]
#[('allNp', 'http://www.wikidata.org/entity/Q38104'), ('allNpname', 'Nobel Prize in Physics')]
#[('allNp', 'http://www.wikidata.org/entity/Q44585'), ('allNpname', 'Nobel Prize in Chemistry')]
#[('allNp', 'http://www.wikidata.org/entity/Q47170'), ('allNpname', 'Prize in Economic Sciences in Memory of Alfred Nobel')]
#[('allNp', 'http://www.wikidata.org/entity/Q80061'), ('allNpname', 'Nobel Prize in Physiology or Medicine')]
# VALUES ?award {Q35637 Q37922 Q38104 Q44585 Q47170 Q80061 }
queryString = """
SELECT DISTINCT  ?country ?countrylabel  
WHERE {
    
    # ?person wdt:P19 ?birthPlace;
            wdt:P166 ?award .
     # ?award wdt:P279 wd:Q7191.
    
    # ?birthPlace wdt:P17 ?country.
    # ?award  wdt:P279 wd:Q7191.
    # ?country sc:name ?countrylabel .
    
} group by ?countrylabel ?country
having (count(DISTINCT(?award))>5)
order by ?countrylabel




"""
print("Results")
x=run_query(queryString)
# Out:
# Results
# [('country', 'http://www.wikidata.org/entity/Q40'), ('countrylabel', 'Austria')]
# [('country', 'http://www.wikidata.org/entity/Q16'), ('countrylabel', 'Canada')]
# [('country', 'http://www.wikidata.org/entity/Q142'), ('countrylabel', 'France')]
# [('country', 'http://www.wikidata.org/entity/Q183'), ('countrylabel', 'Germany')]
# [('country', 'http://www.wikidata.org/entity/Q668'), ('countrylabel', 'India')]
# [('country', 'http://www.wikidata.org/entity/Q38'), ('countrylabel', 'Italy')]
# [('country', 'http://www.wikidata.org/entity/Q20'), ('countrylabel', 'Norway')]
# [('country', 'http://www.wikidata.org/entity/Q36'), ('countrylabel', 'Poland')]
# [('country', 'http://www.wikidata.org/entity/Q159'), ('countrylabel', 'Russia')]
# [('country', 'http://www.wikidata.org/entity/Q34'), ('countrylabel', 'Sweden')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countrylabel', 'United Kingdom')]
# [('country', 'http://www.wikidata.org/entity/Q30'), ('countrylabel', 'United States of America')]
# 12

# %% [markdown]
# ## Task 6
# Amongst the physicists who won the Nobel Prize in Physics, find who had discovered or invented at least 3 things (the result set must be a list of triples physicist IRI, label and #discoveries ).

# %%
#[('p', 'http://www.wikidata.org/prop/direct/P61'), ('name', 'discoverer or inventor')]
#[('job', 'http://www.wikidata.org/entity/Q169470'), ('jobname', 'physicist')]
#[('p', 'http://www.wikidata.org/prop/direct/P166'), ('pName', 'award received'),
#[('award', 'http://www.wikidata.org/entity/Q38104'), ('awardName', 'Nobel Prize in Physics')]

queryString = """
SELECT DISTINCT    ?person ?personName (count (?discovery) AS ?Number)
WHERE {
    
    #being pysict
    # ?person wdt:P106 wd:Q169470.
    
    #winner of Nobel of pysics
    # ?person wdt:P166 wd:Q38104.
    
    #invented or discovered something
    # ?discovery wdt:P61 ?person .
    
    # ?person sc:name ?personName .
    
   
} group by  ?person ?personName 
having (count (?discovery)>=3)

LIMIT 10
"""
print("Results")
x=run_query(queryString)
# Out:
# Results
# [('person', 'http://www.wikidata.org/entity/Q193803'), ('personName', 'Roger Penrose'), ('Number', '6')]
# [('person', 'http://www.wikidata.org/entity/Q160518'), ('personName', 'Gustaf Dalén'), ('Number', '4')]
# [('person', 'http://www.wikidata.org/entity/Q8753'), ('personName', 'Enrico Fermi'), ('Number', '6')]
# [('person', 'http://www.wikidata.org/entity/Q123975'), ('personName', 'Michel Mayor'), ('Number', '12')]
# [('person', 'http://www.wikidata.org/entity/Q173028'), ('personName', 'Emilio G. Segrè'), ('Number', '3')]
# [('person', 'http://www.wikidata.org/entity/Q47480'), ('personName', 'Paul Dirac'), ('Number', '3')]
# [('person', 'http://www.wikidata.org/entity/Q937'), ('personName', 'Albert Einstein'), ('Number', '10')]
# [('person', 'http://www.wikidata.org/entity/Q37463'), ('personName', 'Pierre Curie'), ('Number', '4')]
# [('person', 'http://www.wikidata.org/entity/Q47285'), ('personName', 'J. J. Thomson'), ('Number', '3')]
# 9

# %% [markdown]
# Final query for this task

# %%
#[('p', 'http://www.wikidata.org/prop/direct/P61'), ('name', 'discoverer or inventor')]
#[('job', 'http://www.wikidata.org/entity/Q169470'), ('jobname', 'physicist')]
#[('p', 'http://www.wikidata.org/prop/direct/P166'), ('pName', 'award received'),
#[('award', 'http://www.wikidata.org/entity/Q38104'), ('awardName', 'Nobel Prize in Physics')]

queryString = """
SELECT DISTINCT    ?person ?personName (count (?discovery) AS ?Number)
WHERE {
    
    #being pysict
    # ?person wdt:P106 wd:Q169470.
    
    #winner of Nobel of pysics
    # ?person wdt:P166 wd:Q38104.
    
    #invented or discovered something
    # ?discovery wdt:P61 ?person .
    
   
    
    # ?person sc:name ?personName .
    
   
} group by  ?person ?personName 
having (count (?discovery)>=3)


"""
print("Results")
x=run_query(queryString)
# Out:
# Results
# [('person', 'http://www.wikidata.org/entity/Q193803'), ('personName', 'Roger Penrose'), ('Number', '6')]
# [('person', 'http://www.wikidata.org/entity/Q160518'), ('personName', 'Gustaf Dalén'), ('Number', '4')]
# [('person', 'http://www.wikidata.org/entity/Q8753'), ('personName', 'Enrico Fermi'), ('Number', '6')]
# [('person', 'http://www.wikidata.org/entity/Q123975'), ('personName', 'Michel Mayor'), ('Number', '12')]
# [('person', 'http://www.wikidata.org/entity/Q173028'), ('personName', 'Emilio G. Segrè'), ('Number', '3')]
# [('person', 'http://www.wikidata.org/entity/Q47480'), ('personName', 'Paul Dirac'), ('Number', '3')]
# [('person', 'http://www.wikidata.org/entity/Q937'), ('personName', 'Albert Einstein'), ('Number', '10')]
# [('person', 'http://www.wikidata.org/entity/Q37463'), ('personName', 'Pierre Curie'), ('Number', '4')]
# [('person', 'http://www.wikidata.org/entity/Q47285'), ('personName', 'J. J. Thomson'), ('Number', '3')]
# 9

# %% [markdown]
# ## Task 7
# Amongst the physicists who won the Nobel Prize in Physics, find who taught in the university of his/her city of birth (the result set must be a list of elements of the form physicist IRI, label, university IRI and label).

# %%
#[('job', 'http://www.wikidata.org/entity/Q169470'), ('jobname', 'physicist')]
#[('p', 'http://www.wikidata.org/prop/direct/P166'), ('pName', 'award received'),
#[('award', 'http://www.wikidata.org/entity/Q38104'), ('awardName', 'Nobel Prize in Physics')]
#[('work', 'http://www.wikidata.org/entity/Q1622272'), ('workName', 'university teacher')]
#all physicists who won the Nobel Prize in Physics, who taught in "a" university
queryString = """
SELECT DISTINCT    ?person ?personName 
WHERE {
    
    #being pysict
    # ?person wdt:P106 wd:Q169470.
    
    #winner of Nobel of pysics
    # ?person wdt:P166 wd:Q38104.
    
    #being university teacher
    # ?person wdt:P106 wd:Q1622272.
    
     #persons BirthPlace 
    # ?person wdt:P19 ?birthPlace.
    
    
    
    
    #labels
    # ?person sc:name ?personName .
    
   
} 
LIMIT 10
"""
print("Results")
x=run_query(queryString)
# Out:
# Results
# [('person', 'http://www.wikidata.org/entity/Q57072'), ('personName', 'Otto Stern')]
# [('person', 'http://www.wikidata.org/entity/Q71024'), ('personName', 'Klaus von Klitzing')]
# [('person', 'http://www.wikidata.org/entity/Q65807'), ('personName', 'Reinhard Genzel')]
# [('person', 'http://www.wikidata.org/entity/Q71022'), ('personName', 'Ernst Ruska')]
# [('person', 'http://www.wikidata.org/entity/Q190495'), ('personName', 'Henry Way Kendall')]
# [('person', 'http://www.wikidata.org/entity/Q71023'), ('personName', 'Alfred Kastler')]
# [('person', 'http://www.wikidata.org/entity/Q191922'), ('personName', 'Frederick Reines')]
# [('person', 'http://www.wikidata.org/entity/Q57063'), ('personName', 'Philipp Lenard')]
# [('person', 'http://www.wikidata.org/entity/Q57067'), ('personName', 'Max von Laue')]
# [('person', 'http://www.wikidata.org/entity/Q57068'), ('personName', 'Wilhelm Wien')]
# 10

# %%
#[('person', 'http://www.wikidata.org/entity/Q71024'), ('personName', 'Klaus von Klitzing')]
#checking a random found node (university)from previous query to find the property related to location of university

queryString = """
SELECT DISTINCT  ?p ?name
WHERE {
   wd:Q1622272 ?p ?obj.
   # ?p sc:name ?name.
}
LIMIT 100
"""
print("Results")
x=run_query(queryString)
#did not work so using another way
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P1036'), ('name', 'Dewey Decimal Classification')]
# [('p', 'http://www.wikidata.org/prop/direct/P1889'), ('name', 'different from')]
# [('p', 'http://www.wikidata.org/prop/direct/P227'), ('name', 'GND ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P244'), ('name', 'Library of Congress authority ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2671'), ('name', 'Google Knowledge Graph ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P268'), ('name', 'Bibliothèque nationale de France ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('name', 'subclass of')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('name', 'instance of')]
# [('p', 'http://www.wikidata.org/prop/direct/P3417'), ('name', 'Quora topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3911'), ('name', 'STW Thesaurus for Economics ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P425'), ('name', 'field of this occupation')]
# [('p', 'http://www.wikidata.org/prop/direct/P460'), ('name', 'said to be the same as')]
# [('p', 'http://www.wikidata.org/prop/direct/P487'), ('name', 'Unicode character')]
# [('p', 'http://www.wikidata.org/prop/direct/P8365'), ('name', 'Thesaurus Sozialwissenschaften ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P910'), ('name', "topic's main category")]
# [('p', 'http://www.wikidata.org/prop/direct/P920'), ('name', 'LEM ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P950'), ('name', 'Biblioteca Nacional de España ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P952'), ('name', 'ISCO-88 occupation code')]
# 18

# %%
#[('p', 'http://www.wikidata.org/prop/direct/P108'), ('pname', 'employer'),
#('inv', 'http://www.wikidata.org/entity/Q3918'), ('invName', 'university')]
#[('inv', 'http://www.wikidata.org/entity/Q937'), ('invName', 'Albert Einstein')]

#finding place of teaching 
queryString = """
SELECT DISTINCT  ?p ?name ?obj ?objname
WHERE {
    wd:Q937 wdt:P108 ?p.
    # ?p wdt:P31 ?obj .
    
    # ?p sc:name ?name.
    # ?obj sc:name ?objname
}

LIMIT 100
"""
print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/entity/Q819187'), ('name', 'Deutsche Physikalische Gesellschaft'), ('obj', 'http://www.wikidata.org/entity/Q15911314'), ('objname', 'association')]
# [('p', 'http://www.wikidata.org/entity/Q635642'), ('name', 'Institute for Advanced Study'), ('obj', 'http://www.wikidata.org/entity/Q166118'), ('objname', 'archive')]
# [('p', 'http://www.wikidata.org/entity/Q168756'), ('name', 'University of California, Berkeley'), ('obj', 'http://www.wikidata.org/entity/Q20971972'), ('objname', 'Original Public Ivy')]
# [('p', 'http://www.wikidata.org/entity/Q168756'), ('name', 'University of California, Berkeley'), ('obj', 'http://www.wikidata.org/entity/Q23002039'), ('objname', 'public educational institution of the United States')]
# [('p', 'http://www.wikidata.org/entity/Q168756'), ('name', 'University of California, Berkeley'), ('obj', 'http://www.wikidata.org/entity/Q615150'), ('objname', 'land-grant university')]
# [('p', 'http://www.wikidata.org/entity/Q708038'), ('name', 'Kaiser Wilhelm Society'), ('obj', 'http://www.wikidata.org/entity/Q748019'), ('objname', 'scientific society')]
# [('p', 'http://www.wikidata.org/entity/Q329464'), ('name', 'Royal Prussian Academy of Sciences'), ('obj', 'http://www.wikidata.org/entity/Q414147'), ('objname', 'academy of sciences')]
# [('p', 'http://www.wikidata.org/entity/Q11942'), ('name', 'ETH Zürich'), ('obj', 'http://www.wikidata.org/entity/Q1371037'), ('objname', 'institute of technology')]
# [('p', 'http://www.wikidata.org/entity/Q70'), ('name', 'Bern'), ('obj', 'http://www.wikidata.org/entity/Q1187811'), ('objname', 'college town')]
# [('p', 'http://www.wikidata.org/entity/Q70'), ('name', 'Bern'), ('obj', 'http://www.wikidata.org/entity/Q14770218'), ('objname', 'cantonal capital of Switzerland')]
# [('p', 'http://www.wikidata.org/entity/Q70'), ('name', 'Bern'), ('obj', 'http://www.wikidata.org/entity/Q1549591'), ('objname', 'big city')]
# [('p', 'http://www.wikidata.org/entity/Q21578'), ('name', 'Princeton University'), ('obj', 'http://www.wikidata.org/entity/Q15936437'), ('objname', 'research university')]
# [('p', 'http://www.wikidata.org/entity/Q21578'), ('name', 'Princeton University'), ('obj', 'http://www.wikidata.org/entity/Q23002054'), ('objname', 'private not-for-profit educational institution')]
# [('p', 'http://www.wikidata.org/entity/Q156598'), ('name', 'Leiden University'), ('obj', 'http://www.wikidata.org/entity/Q3918'), ('objname', 'university')]
# [('p', 'http://www.wikidata.org/entity/Q1729754'), ('name', 'German University in Prague'), ('obj', 'http://www.wikidata.org/entity/Q3918'), ('objname', 'university')]
# [('p', 'http://www.wikidata.org/entity/Q206702'), ('name', 'University of Zurich'), ('obj', 'http://www.wikidata.org/entity/Q3918'), ('objname', 'university')]
# [('p', 'http://www.wikidata.org/entity/Q685539'), ('name', 'Swiss Federal Institute of Intellectual Property'), ('obj', 'http://www.wikidata.org/entity/Q43229'), ('objname', 'organization')]
# [('p', 'http://www.wikidata.org/entity/Q659080'), ('name', 'University of Bern'), ('obj', 'http://www.wikidata.org/entity/Q45400320'), ('objname', 'open-access publisher')]
# [('p', 'http://www.wikidata.org/entity/Q152087'), ('name', 'Humboldt University of Berlin'), ('obj', 'http://www.wikidata.org/entity/Q45400320'), ('objname', 'open-access publisher')]
# [('p', 'http://www.wikidata.org/entity/Q70'), ('name', 'Bern'), ('obj', 'http://www.wikidata.org/entity/Q5119'), ('objname', 'capital')]
# [('p', 'http://www.wikidata.org/entity/Q70'), ('name', 'Bern'), ('obj', 'http://www.wikidata.org/entity/Q537250'), ('objname', 'federal city')]
# [('p', 'http://www.wikidata.org/entity/Q70'), ('name', 'Bern'), ('obj', 'http://www.wikidata.org/entity/Q54935504'), ('objname', 'city of Switzerland')]
# [('p', 'http://www.wikidata.org/entity/Q70'), ('name', 'Bern'), ('obj', 'http://www.wikidata.org/entity/Q56061'), ('objname', 'administrative territorial entity')]
# [('p', 'http://www.wikidata.org/entity/Q70'), ('name', 'Bern'), ('obj', 'http://www.wikidata.org/entity/Q70208'), ('objname', 'municipality of Switzerland')]
# [('p', 'http://www.wikidata.org/entity/Q21578'), ('name', 'Princeton University'), ('obj', 'http://www.wikidata.org/entity/Q902104'), ('objname', 'private university')]
# [('p', 'http://www.wikidata.org/entity/Q635642'), ('name', 'Institute for Advanced Study'), ('obj', 'http://www.wikidata.org/entity/Q31855'), ('objname', 'research institute')]
# [('p', 'http://www.wikidata.org/entity/Q168756'), ('name', 'University of California, Berkeley'), ('obj', 'http://www.wikidata.org/entity/Q62078547'), ('objname', 'public research university')]
# [('p', 'http://www.wikidata.org/entity/Q152087'), ('name', 'Humboldt University of Berlin'), ('obj', 'http://www.wikidata.org/entity/Q62078547'), ('objname', 'public research university')]
# [('p', 'http://www.wikidata.org/entity/Q819187'), ('name', 'Deutsche Physikalische Gesellschaft'), ('obj', 'http://www.wikidata.org/entity/Q1391145'), ('objname', 'professional society')]
# [('p', 'http://www.wikidata.org/entity/Q168756'), ('name', 'University of California, Berkeley'), ('obj', 'http://www.wikidata.org/entity/Q11422631'), ('objname', 'United Nations Depository Library')]
# [('p', 'http://www.wikidata.org/entity/Q152087'), ('name', 'Humboldt University of Berlin'), ('obj', 'http://www.wikidata.org/entity/Q1767829'), ('objname', 'comprehensive university')]
# [('p', 'http://www.wikidata.org/entity/Q206702'), ('name', 'University of Zurich'), ('obj', 'http://www.wikidata.org/entity/Q1767829'), ('objname', 'comprehensive university')]
# [('p', 'http://www.wikidata.org/entity/Q659080'), ('name', 'University of Bern'), ('obj', 'http://www.wikidata.org/entity/Q1767829'), ('objname', 'comprehensive university')]
# [('p', 'http://www.wikidata.org/entity/Q659080'), ('name', 'University of Bern'), ('obj', 'http://www.wikidata.org/entity/Q875538'), ('objname', 'public university')]
# [('p', 'http://www.wikidata.org/entity/Q31519'), ('name', 'Charles University'), ('obj', 'http://www.wikidata.org/entity/Q875538'), ('objname', 'public university')]
# [('p', 'http://www.wikidata.org/entity/Q168756'), ('name', 'University of California, Berkeley'), ('obj', 'http://www.wikidata.org/entity/Q3053337'), ('objname', 'employer')]
# [('p', 'http://www.wikidata.org/entity/Q21578'), ('name', 'Princeton University'), ('obj', 'http://www.wikidata.org/entity/Q1188663'), ('objname', 'Colonial Colleges')]
# 37

# %%
#[('obj', 'http://www.wikidata.org/entity/Q3918'), ('objname', 'university')]
#had been employed by a university 
queryString = """
SELECT DISTINCT    ?person ?personName 
WHERE {
    
    #being pysict
    # ?person wdt:P106 wd:Q169470.
    
    #winner of Nobel of pysics
    # ?person wdt:P166 wd:Q38104.
    
    #being university teacher
    # ?person wdt:P106 wd:Q1622272.
    
     #persons BirthPlace 
    # ?person wdt:P19 ?birthPlace.
    
    #university employed 
    # ?person wdt:P108 ?university.
    # ?university wdt:P31 wd:Q3918.
    
    
    
    #labels
    # ?person sc:name ?personName .
    
   
} 
LIMIT 10
"""
print("Results")
x=run_query(queryString)
# Out:
# Results
# [('person', 'http://www.wikidata.org/entity/Q190495'), ('personName', 'Henry Way Kendall')]
# [('person', 'http://www.wikidata.org/entity/Q191922'), ('personName', 'Frederick Reines')]
# [('person', 'http://www.wikidata.org/entity/Q57063'), ('personName', 'Philipp Lenard')]
# [('person', 'http://www.wikidata.org/entity/Q57067'), ('personName', 'Max von Laue')]
# [('person', 'http://www.wikidata.org/entity/Q57070'), ('personName', 'Gustav Ludwig Hertz')]
# [('person', 'http://www.wikidata.org/entity/Q57100'), ('personName', 'Maria Goeppert Mayer')]
# [('person', 'http://www.wikidata.org/entity/Q39246'), ('personName', 'Richard Feynman')]
# [('person', 'http://www.wikidata.org/entity/Q130975'), ('personName', 'Robert A. Millikan')]
# [('person', 'http://www.wikidata.org/entity/Q131721'), ('personName', 'Johannes Diderik van der Waals')]
# [('person', 'http://www.wikidata.org/entity/Q163415'), ('personName', 'William Shockley')]
# 10

# %%
#finding location property for university 
#[('p', 'http://www.wikidata.org/entity/Q206702'), ('name', 'University of Zurich')
#('obj', 'http://www.wikidata.org/entity/Q3918'), ('objname', 'university')]
queryString = """
SELECT DISTINCT  ?p ?name ?obj ?objname
WHERE {
   wd:Q206702 ?p ?obj .
    # ?p sc:name ?name.
    # ?obj sc:name ?objname
   
}

LIMIT 100
"""
print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P159'), ('name', 'headquarters location'), ('obj', 'http://www.wikidata.org/entity/Q72'), ('objname', 'Zürich')]
# [('p', 'http://www.wikidata.org/prop/direct/P485'), ('name', 'archives at'), ('obj', 'http://www.wikidata.org/entity/Q31839584'), ('objname', 'UZH Archives')]
# [('p', 'http://www.wikidata.org/prop/direct/P355'), ('name', 'subsidiary'), ('obj', 'http://www.wikidata.org/entity/Q15850649'), ('objname', 'Faculty of Theology of the University of Zurich')]
# [('p', 'http://www.wikidata.org/prop/direct/P485'), ('name', 'archives at'), ('obj', 'http://www.wikidata.org/entity/Q2324789'), ('objname', 'Staatsarchiv des Kantons Zürich')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('name', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q27490237'), ('objname', 'Main Library of the University of Zurich')]
# [('p', 'http://www.wikidata.org/prop/direct/P1830'), ('name', 'owner of'), ('obj', 'http://www.wikidata.org/entity/Q38141077'), ('objname', 'Oerlikon Campus')]
# [('p', 'http://www.wikidata.org/prop/direct/P2283'), ('name', 'uses'), ('obj', 'http://www.wikidata.org/entity/Q66647864'), ('objname', 'University of Zurich, main building')]
# [('p', 'http://www.wikidata.org/prop/direct/P4195'), ('name', 'category for employees of the organization'), ('obj', 'http://www.wikidata.org/entity/Q7997450'), ('objname', 'Category:University of Zurich faculty')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('name', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q856547'), ('objname', 'University of Zurich Law Library')]
# [('p', 'http://www.wikidata.org/prop/direct/P7561'), ('name', 'category for the interior of the item'), ('obj', 'http://www.wikidata.org/entity/Q86119132'), ('objname', 'Category:Interior of the University of Zurich')]
# [('p', 'http://www.wikidata.org/prop/direct/P910'), ('name', "topic's main category"), ('obj', 'http://www.wikidata.org/entity/Q8946129'), ('objname', 'Category:University of Zurich')]
# [('p', 'http://www.wikidata.org/prop/direct/P3876'), ('name', 'category for alumni of educational institution'), ('obj', 'http://www.wikidata.org/entity/Q9758902'), ('objname', 'Category:University of Zurich alumni')]
# [('p', 'http://www.wikidata.org/prop/direct/P17'), ('name', 'country'), ('obj', 'http://www.wikidata.org/entity/Q39'), ('objname', 'Switzerland')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('name', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q3918'), ('objname', 'university')]
# [('p', 'http://www.wikidata.org/prop/direct/P463'), ('name', 'member of'), ('obj', 'http://www.wikidata.org/entity/Q868940'), ('objname', 'European University Association')]
# [('p', 'http://www.wikidata.org/prop/direct/P463'), ('name', 'member of'), ('obj', 'http://www.wikidata.org/entity/Q1559701'), ('objname', 'Informationsdienst Wissenschaft e.V.')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('name', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q1767829'), ('objname', 'comprehensive university')]
# 17

# %%
#finding location property for university 
#[('p', 'http://www.wikidata.org/entity/Q206702'), ('name', 'University of Zurich')
#('obj', 'http://www.wikidata.org/entity/Q3918'), ('objname', 'university')]
queryString = """
SELECT DISTINCT  ?x
WHERE {
   wd:Q206702 wdt:P159 ?x.
   # ?x sc:name ?name .
}

LIMIT 100
"""
print("Results")
x=run_query(queryString)
# Out:
# Results
# [('x', 'http://www.wikidata.org/entity/Q72')]
# 1

# %%
#[('p', 'http://www.wikidata.org/prop/direct/P159'), ('name', 'headquarters location'), 
#('obj', 'http://www.wikidata.org/entity/Q72'), ('objname', 'Zürich')]

#finding university location 
queryString = """
SELECT DISTINCT    ?person ?personName 
WHERE {
    
    #being pysict
    # ?person wdt:P106 wd:Q169470.
    
    #winner of Nobel of pysics
    # ?person wdt:P166 wd:Q38104.
    
    #being university teacher
    # ?person wdt:P106 wd:Q1622272.
    
     #persons BirthPlace 
    # ?person wdt:P19 ?birthPlace.
    
    #university employed 
    # ?person wdt:P108 ?university.
    # ?university wdt:P31 wd:Q3918.
    
    #university location 
    
    # ?university wdt:P159 ?uniLocation .
    
    
    
    #labels
    # ?person sc:name ?personName .
    
   
} 
LIMIT 100
"""
print("Results")
x=run_query(queryString)
# Out:
# Results
# [('person', 'http://www.wikidata.org/entity/Q133267'), ('personName', 'Lev Landau')]
# [('person', 'http://www.wikidata.org/entity/Q201853'), ('personName', 'David Lee')]
# [('person', 'http://www.wikidata.org/entity/Q83557'), ('personName', 'Nikolay Basov')]
# [('person', 'http://www.wikidata.org/entity/Q556543'), ('personName', 'Gérard Mourou')]
# [('person', 'http://www.wikidata.org/entity/Q192712'), ('personName', 'Kai Siegbahn')]
# [('person', 'http://www.wikidata.org/entity/Q54945'), ('personName', 'Hannes Alfvén')]
# [('person', 'http://www.wikidata.org/entity/Q170741'), ('personName', 'Manne Siegbahn')]
# [('person', 'http://www.wikidata.org/entity/Q131729'), ('personName', 'Lawrence Bragg')]
# [('person', 'http://www.wikidata.org/entity/Q184499'), ('personName', 'Patrick Blackett, Baron Blackett')]
# [('person', 'http://www.wikidata.org/entity/Q7085'), ('personName', 'Niels Bohr')]
# [('person', 'http://www.wikidata.org/entity/Q155794'), ('personName', 'Hans Bethe')]
# [('person', 'http://www.wikidata.org/entity/Q57063'), ('personName', 'Philipp Lenard')]
# [('person', 'http://www.wikidata.org/entity/Q127944'), ('personName', 'Arthur Compton')]
# [('person', 'http://www.wikidata.org/entity/Q79000'), ('personName', 'Pieter Zeeman')]
# [('person', 'http://www.wikidata.org/entity/Q191922'), ('personName', 'Frederick Reines')]
# [('person', 'http://www.wikidata.org/entity/Q127234'), ('personName', 'Albert A. Michelson')]
# [('person', 'http://www.wikidata.org/entity/Q83552'), ('personName', 'Alexander Prokhorov')]
# [('person', 'http://www.wikidata.org/entity/Q57070'), ('personName', 'Gustav Ludwig Hertz')]
# [('person', 'http://www.wikidata.org/entity/Q40904'), ('personName', 'Werner Heisenberg')]
# [('person', 'http://www.wikidata.org/entity/Q70532'), ('personName', 'Hans Georg Dehmelt')]
# [('person', 'http://www.wikidata.org/entity/Q163415'), ('personName', 'William Shockley')]
# [('person', 'http://www.wikidata.org/entity/Q71013'), ('personName', 'Theodor W. Hänsch')]
# [('person', 'http://www.wikidata.org/entity/Q123022'), ('personName', 'Felix Bloch')]
# [('person', 'http://www.wikidata.org/entity/Q205954'), ('personName', 'Eric Allin Cornell')]
# [('person', 'http://www.wikidata.org/entity/Q130113'), ('personName', 'Robert Hofstadter')]
# [('person', 'http://www.wikidata.org/entity/Q172466'), ('personName', 'Steven Chu')]
# [('person', 'http://www.wikidata.org/entity/Q206379'), ('personName', 'Carl Wieman')]
# [('person', 'http://www.wikidata.org/entity/Q192106'), ('personName', 'Burton Richter')]
# [('person', 'http://www.wikidata.org/entity/Q189997'), ('personName', 'Robert B. Laughlin')]
# [('person', 'http://www.wikidata.org/entity/Q201470'), ('personName', 'Richard E. Taylor')]
# [('person', 'http://www.wikidata.org/entity/Q206405'), ('personName', 'Douglas Osheroff')]
# [('person', 'http://www.wikidata.org/entity/Q190495'), ('personName', 'Henry Way Kendall')]
# [('person', 'http://www.wikidata.org/entity/Q179282'), ('personName', 'Steven Weinberg')]
# [('person', 'http://www.wikidata.org/entity/Q165969'), ('personName', 'Isidor Isaac Rabi')]
# [('person', 'http://www.wikidata.org/entity/Q2128461'), ('personName', 'Rainer Weiss')]
# [('person', 'http://www.wikidata.org/entity/Q183270'), ('personName', 'Edward Mills Purcell')]
# [('person', 'http://www.wikidata.org/entity/Q187822'), ('personName', 'Jerome Isaac Friedman')]
# [('person', 'http://www.wikidata.org/entity/Q184566'), ('personName', 'Charles Hard Townes')]
# [('person', 'http://www.wikidata.org/entity/Q192715'), ('personName', 'Samuel C. C. Ting')]
# [('person', 'http://www.wikidata.org/entity/Q107450'), ('personName', 'Frank Wilczek')]
# [('person', 'http://www.wikidata.org/entity/Q201506'), ('personName', 'Clifford Shull')]
# [('person', 'http://www.wikidata.org/entity/Q76462'), ('personName', 'Wolfgang Ketterle')]
# [('person', 'http://www.wikidata.org/entity/Q151746'), ('personName', 'François Englert')]
# [('person', 'http://www.wikidata.org/entity/Q323320'), ('personName', 'Kip S. Thorne')]
# [('person', 'http://www.wikidata.org/entity/Q193803'), ('personName', 'Roger Penrose')]
# [('person', 'http://www.wikidata.org/entity/Q41688'), ('personName', 'Hendrik Lorentz')]
# [('person', 'http://www.wikidata.org/entity/Q937'), ('personName', 'Albert Einstein')]
# [('person', 'http://www.wikidata.org/entity/Q184592'), ('personName', "Gerard 't Hooft")]
# [('person', 'http://www.wikidata.org/entity/Q155790'), ('personName', 'Eugene Wigner')]
# [('person', 'http://www.wikidata.org/entity/Q189987'), ('personName', 'Nicolaas Bloembergen')]
# [('person', 'http://www.wikidata.org/entity/Q62891'), ('personName', 'Heike Kamerlingh Onnes')]
# [('person', 'http://www.wikidata.org/entity/Q190697'), ('personName', 'Claude Cohen-Tannoudji')]
# [('person', 'http://www.wikidata.org/entity/Q202149'), ('personName', 'Martinus J. G. Veltman')]
# [('person', 'http://www.wikidata.org/entity/Q181369'), ('personName', 'Chen-ning Yang')]
# [('person', 'http://www.wikidata.org/entity/Q64188'), ('personName', 'Roy J. Glauber')]
# [('person', 'http://www.wikidata.org/entity/Q40262'), ('personName', 'David Gross')]
# [('person', 'http://www.wikidata.org/entity/Q193655'), ('personName', 'John Hasbrouck Van Vleck')]
# [('person', 'http://www.wikidata.org/entity/Q1002250'), ('personName', 'Duncan Haldane')]
# [('person', 'http://www.wikidata.org/entity/Q39246'), ('personName', 'Richard Feynman')]
# [('person', 'http://www.wikidata.org/entity/Q130975'), ('personName', 'Robert A. Millikan')]
# [('person', 'http://www.wikidata.org/entity/Q169366'), ('personName', 'Carl David Anderson')]
# [('person', 'http://www.wikidata.org/entity/Q46120'), ('personName', 'William Alfred Fowler')]
# [('person', 'http://www.wikidata.org/entity/Q44286'), ('personName', 'Rudolf Mössbauer')]
# [('person', 'http://www.wikidata.org/entity/Q107407'), ('personName', 'Hugh David Politzer')]
# [('person', 'http://www.wikidata.org/entity/Q160522'), ('personName', 'Charles Glover Barkla')]
# [('person', 'http://www.wikidata.org/entity/Q57100'), ('personName', 'Maria Goeppert Mayer')]
# [('person', 'http://www.wikidata.org/entity/Q186481'), ('personName', 'Riccardo Giacconi')]
# [('person', 'http://www.wikidata.org/entity/Q57066'), ('personName', 'James Franck')]
# [('person', 'http://www.wikidata.org/entity/Q57067'), ('personName', 'Max von Laue')]
# [('person', 'http://www.wikidata.org/entity/Q122298'), ('personName', 'Karl Alexander Müller')]
# [('person', 'http://www.wikidata.org/entity/Q133222'), ('personName', 'Clinton Davisson')]
# [('person', 'http://www.wikidata.org/entity/Q106494'), ('personName', 'Konstantin Novoselov')]
# [('person', 'http://www.wikidata.org/entity/Q71016'), ('personName', 'Herbert Kroemer')]
# [('person', 'http://www.wikidata.org/entity/Q153201'), ('personName', 'John Robert Schrieffer')]
# [('person', 'http://www.wikidata.org/entity/Q60429'), ('personName', 'C. V. Raman')]
# [('person', 'http://www.wikidata.org/entity/Q192685'), ('personName', 'Joseph Hooton Taylor')]
# [('person', 'http://www.wikidata.org/entity/Q192695'), ('personName', 'Leon M. Lederman')]
# [('person', 'http://www.wikidata.org/entity/Q131721'), ('personName', 'Johannes Diderik van der Waals')]
# [('person', 'http://www.wikidata.org/entity/Q11443689'), ('personName', 'Hiroshi Amano')]
# 79

# %%
#Checking the outputs
queryString = """
SELECT DISTINCT   ?personName ?universityName ?uniloc ?bloc
WHERE {
    
    #being pysict
    # ?person wdt:P106 wd:Q169470.
    
    #winner of Nobel of pysics
    # ?person wdt:P166 wd:Q38104.
    
    #being university teacher
    # ?person wdt:P106 wd:Q1622272.
    
     #persons BirthPlace 
    # ?person wdt:P19 ?birthPlace.
    
    #university employed 
    # ?person wdt:P108 ?university.
    # ?university wdt:P31 wd:Q3918.
    
    #university location 
    
    # ?university wdt:P159 ?uniLocation .
    
    
    
    #labels
    # ?person sc:name ?personName .
    # ?university sc:name ?universityName.
    # ?uniLocation sc:name ?uniloc.
    # ?birthPlace sc:name ?bloc.
   
} group by   ?personName ?u ?b
order by ?personName
LIMIT 1000
"""
print("Results")
x=run_query(queryString)
# Out:
# Results
# [('personName', 'Albert A. Michelson'), ('universityName', 'Case Western Reserve University'), ('uniloc', 'Cleveland'), ('bloc', 'Strzelno')]
# [('personName', 'Albert Einstein'), ('universityName', 'University of Zurich'), ('uniloc', 'Zürich'), ('bloc', 'Ulm')]
# [('personName', 'Albert Einstein'), ('universityName', 'Leiden University'), ('uniloc', 'Leiden'), ('bloc', 'Ulm')]
# [('personName', 'Albert Einstein'), ('universityName', 'German University in Prague'), ('uniloc', 'Prague'), ('bloc', 'Ulm')]
# [('personName', 'Alexander Prokhorov'), ('universityName', 'Moscow State University'), ('uniloc', 'Moscow'), ('bloc', 'Atherton')]
# [('personName', 'Alexander Prokhorov'), ('universityName', 'Moscow Institute of Physics and Technology'), ('uniloc', 'Dolgoprudny'), ('bloc', 'Atherton')]
# [('personName', 'Arthur Compton'), ('universityName', 'Washington University in St.\xa0Louis'), ('uniloc', 'St. Louis'), ('bloc', 'Wooster')]
# [('personName', 'Arthur Compton'), ('universityName', 'Massachusetts Institute of Technology'), ('uniloc', 'Cambridge'), ('bloc', 'Wooster')]
# [('personName', 'Burton Richter'), ('universityName', 'Stanford University'), ('uniloc', 'Stanford'), ('bloc', 'New York City')]
# [('personName', 'C. V. Raman'), ('universityName', 'Banaras Hindu University'), ('uniloc', 'Varanasi'), ('bloc', 'Trichy')]
# [('personName', 'Carl David Anderson'), ('universityName', 'California Institute of Technology'), ('uniloc', 'California'), ('bloc', 'New York City')]
# [('personName', 'Carl Wieman'), ('universityName', 'Stanford University'), ('uniloc', 'Stanford'), ('bloc', 'Corvallis')]
# [('personName', 'Charles Glover Barkla'), ('universityName', 'University of London'), ('uniloc', 'London'), ('bloc', 'Widnes')]
# [('personName', 'Charles Hard Townes'), ('universityName', 'Massachusetts Institute of Technology'), ('uniloc', 'Cambridge'), ('bloc', 'Greenville')]
# [('personName', 'Chen-ning Yang'), ('universityName', 'Leiden University'), ('uniloc', 'Leiden'), ('bloc', 'Hefei County')]
# [('personName', 'Chen-ning Yang'), ('universityName', 'Tsinghua University'), ('uniloc', 'Beijing'), ('bloc', 'Hefei County')]
# [('personName', 'Claude Cohen-Tannoudji'), ('universityName', 'Leiden University'), ('uniloc', 'Leiden'), ('bloc', 'Constantine')]
# [('personName', 'Clifford Shull'), ('universityName', 'Massachusetts Institute of Technology'), ('uniloc', 'Cambridge'), ('bloc', 'Pittsburgh')]
# [('personName', 'Clinton Davisson'), ('universityName', 'University of Virginia'), ('uniloc', 'Charlottesville'), ('bloc', 'Bloomington')]
# [('personName', 'David Gross'), ('universityName', 'Leiden University'), ('uniloc', 'Leiden'), ('bloc', 'Washington, D.C.')]
# [('personName', 'David Gross'), ('universityName', 'University of California, Santa Barbara'), ('uniloc', 'Santa Barbara'), ('bloc', 'Washington, D.C.')]
# [('personName', 'David Lee'), ('universityName', 'Texas A&M University'), ('uniloc', 'College Station'), ('bloc', 'Rye')]
# [('personName', 'David Lee'), ('universityName', 'University of Florida'), ('uniloc', 'Gainesville'), ('bloc', 'Rye')]
# [('personName', 'Douglas Osheroff'), ('universityName', 'Stanford University'), ('uniloc', 'Stanford'), ('bloc', 'Aberdeen')]
# [('personName', 'Duncan Haldane'), ('universityName', 'Leiden University'), ('uniloc', 'Leiden'), ('bloc', 'London')]
# [('personName', 'Edward Mills Purcell'), ('universityName', 'Massachusetts Institute of Technology'), ('uniloc', 'Cambridge'), ('bloc', 'Taylorville')]
# [('personName', 'Eric Allin Cornell'), ('universityName', 'Stanford University'), ('uniloc', 'Stanford'), ('bloc', 'Palo Alto')]
# [('personName', 'Eugene Wigner'), ('universityName', 'Leiden University'), ('uniloc', 'Leiden'), ('bloc', 'Budapest')]
# [('personName', 'Felix Bloch'), ('universityName', 'Stanford University'), ('uniloc', 'Stanford'), ('bloc', 'Zürich')]
# [('personName', 'Felix Bloch'), ('universityName', 'Leiden University'), ('uniloc', 'Leiden'), ('bloc', 'Zürich')]
# [('personName', 'Frank Wilczek'), ('universityName', 'Massachusetts Institute of Technology'), ('uniloc', 'Cambridge'), ('bloc', 'Mineola')]
# [('personName', 'Frank Wilczek'), ('universityName', 'University of California, Santa Barbara'), ('uniloc', 'Santa Barbara'), ('bloc', 'Mineola')]
# [('personName', 'Frank Wilczek'), ('universityName', 'Leiden University'), ('uniloc', 'Leiden'), ('bloc', 'Mineola')]
# [('personName', 'François Englert'), ('universityName', 'Tel Aviv University'), ('uniloc', 'Tel Aviv'), ('bloc', 'Etterbeek')]
# [('personName', 'François Englert'), ('universityName', 'Université libre de Bruxelles'), ('uniloc', 'Avenue Franklin Roosevelt - Franklin Rooseveltlaan'), ('bloc', 'Etterbeek')]
# [('personName', 'Frederick Reines'), ('universityName', 'Case Western Reserve University'), ('uniloc', 'Cleveland'), ('bloc', 'Paterson')]
# [('personName', "Gerard 't Hooft"), ('universityName', 'Utrecht University'), ('uniloc', 'Utrecht'), ('bloc', 'Den Helder')]
# [('personName', "Gerard 't Hooft"), ('universityName', 'Leiden University'), ('uniloc', 'Leiden'), ('bloc', 'Den Helder')]
# [('personName', 'Gustav Ludwig Hertz'), ('universityName', 'Leipzig University'), ('uniloc', 'Leipzig'), ('bloc', 'Hamburg')]
# [('personName', 'Gérard Mourou'), ('universityName', 'University of Rochester'), ('uniloc', 'Rochester'), ('bloc', 'Albertville')]
# [('personName', 'Hannes Alfvén'), ('universityName', 'Uppsala University'), ('uniloc', 'Uppsala'), ('bloc', 'Norrköping')]
# [('personName', 'Hans Bethe'), ('universityName', 'University of Manchester'), ('uniloc', 'Manchester'), ('bloc', 'Strasbourg')]
# [('personName', 'Hans Bethe'), ('universityName', 'Victoria University of Manchester'), ('uniloc', 'Manchester'), ('bloc', 'Strasbourg')]
# [('personName', 'Hans Georg Dehmelt'), ('universityName', 'Duke University'), ('uniloc', 'Durham'), ('bloc', 'Görlitz')]
# [('personName', 'Heike Kamerlingh Onnes'), ('universityName', 'Leiden University'), ('uniloc', 'Leiden'), ('bloc', 'Groningen')]
# [('personName', 'Hendrik Lorentz'), ('universityName', 'Leiden University'), ('uniloc', 'Leiden'), ('bloc', 'Arnhem')]
# [('personName', 'Henry Way Kendall'), ('universityName', 'Massachusetts Institute of Technology'), ('uniloc', 'Cambridge'), ('bloc', 'Boston')]
# [('personName', 'Herbert Kroemer'), ('universityName', 'University of California, Santa Barbara'), ('uniloc', 'Santa Barbara'), ('bloc', 'Weimar')]
# [('personName', 'Hiroshi Amano'), ('universityName', 'Nagoya University'), ('uniloc', 'Nagoya'), ('bloc', 'Hamamatsu')]
# [('personName', 'Hugh David Politzer'), ('universityName', 'California Institute of Technology'), ('uniloc', 'California'), ('bloc', 'New York City')]
# [('personName', 'Isidor Isaac Rabi'), ('universityName', 'Massachusetts Institute of Technology'), ('uniloc', 'Cambridge'), ('bloc', 'Rymanów')]
# [('personName', 'James Franck'), ('universityName', 'Johns Hopkins University'), ('uniloc', 'Baltimore'), ('bloc', 'Hamburg')]
# [('personName', 'Jerome Isaac Friedman'), ('universityName', 'Massachusetts Institute of Technology'), ('uniloc', 'Cambridge'), ('bloc', 'Chicago')]
# [('personName', 'Johannes Diderik van der Waals'), ('universityName', 'University of Amsterdam'), ('uniloc', 'Amsterdam'), ('bloc', 'Leiden')]
# [('personName', 'John Hasbrouck Van Vleck'), ('universityName', 'Leiden University'), ('uniloc', 'Leiden'), ('bloc', 'Middletown')]
# [('personName', 'John Robert Schrieffer'), ('universityName', 'University of California, Santa Barbara'), ('uniloc', 'Santa Barbara'), ('bloc', 'Oak Park')]
# [('personName', 'Joseph Hooton Taylor'), ('universityName', 'University of Massachusetts Amherst'), ('uniloc', 'Amherst'), ('bloc', 'Philadelphia')]
# [('personName', 'Kai Siegbahn'), ('universityName', 'Uppsala University'), ('uniloc', 'Uppsala'), ('bloc', 'Lund')]
# [('personName', 'Karl Alexander Müller'), ('universityName', 'University of Zurich'), ('uniloc', 'Zürich'), ('bloc', 'Basel')]
# [('personName', 'Kip S. Thorne'), ('universityName', 'California Institute of Technology'), ('uniloc', 'California'), ('bloc', 'Logan')]
# [('personName', 'Kip S. Thorne'), ('universityName', 'Leiden University'), ('uniloc', 'Leiden'), ('bloc', 'Logan')]
# [('personName', 'Konstantin Novoselov'), ('universityName', 'University of Manchester'), ('uniloc', 'Manchester'), ('bloc', 'Nizhny Tagil')]
# [('personName', 'Lawrence Bragg'), ('universityName', 'Victoria University of Manchester'), ('uniloc', 'Manchester'), ('bloc', 'Adelaide')]
# [('personName', 'Lawrence Bragg'), ('universityName', 'University of Manchester'), ('uniloc', 'Manchester'), ('bloc', 'Adelaide')]
# [('personName', 'Leon M. Lederman'), ('universityName', 'Illinois Institute of Technology'), ('uniloc', 'Chicago'), ('bloc', 'New York City')]
# [('personName', 'Lev Landau'), ('universityName', 'National University of Kharkiv'), ('uniloc', 'Kharkiv'), ('bloc', 'Baku')]
# [('personName', 'Lev Landau'), ('universityName', 'Moscow Institute of Physics and Technology'), ('uniloc', 'Dolgoprudny'), ('bloc', 'Baku')]
# [('personName', 'Lev Landau'), ('universityName', 'Moscow State University'), ('uniloc', 'Moscow'), ('bloc', 'Baku')]
# [('personName', 'Manne Siegbahn'), ('universityName', 'Uppsala University'), ('uniloc', 'Uppsala'), ('bloc', 'Örebro Nikolai parish')]
# [('personName', 'Manne Siegbahn'), ('universityName', 'Lund University'), ('uniloc', 'Lund'), ('bloc', 'Örebro Nikolai parish')]
# [('personName', 'Maria Goeppert Mayer'), ('universityName', 'Johns Hopkins University'), ('uniloc', 'Baltimore'), ('bloc', 'Katowice')]
# [('personName', 'Martinus J. G. Veltman'), ('universityName', 'Utrecht University'), ('uniloc', 'Utrecht'), ('bloc', 'Waalwijk')]
# [('personName', 'Martinus J. G. Veltman'), ('universityName', 'Leiden University'), ('uniloc', 'Leiden'), ('bloc', 'Waalwijk')]
# [('personName', 'Max von Laue'), ('universityName', 'University of Zurich'), ('uniloc', 'Zürich'), ('bloc', 'Koblenz')]
# [('personName', 'Nicolaas Bloembergen'), ('universityName', 'Leiden University'), ('uniloc', 'Leiden'), ('bloc', 'Dordrecht')]
# [('personName', 'Niels Bohr'), ('universityName', 'University of Manchester'), ('uniloc', 'Manchester'), ('bloc', 'Copenhagen')]
# [('personName', 'Niels Bohr'), ('universityName', 'Victoria University of Manchester'), ('uniloc', 'Manchester'), ('bloc', 'Copenhagen')]
# [('personName', 'Nikolay Basov'), ('universityName', 'National Research Nuclear University'), ('uniloc', 'Moscow'), ('bloc', 'Usman')]
# [('personName', 'Patrick Blackett, Baron Blackett'), ('universityName', 'University of Manchester'), ('uniloc', 'Manchester'), ('bloc', 'London')]
# [('personName', 'Patrick Blackett, Baron Blackett'), ('universityName', 'Victoria University of Manchester'), ('uniloc', 'Manchester'), ('bloc', 'London')]
# [('personName', 'Philipp Lenard'), ('universityName', 'Budapest University of Technology and Economics'), ('uniloc', 'Budapest'), ('bloc', 'Bratislava')]
# [('personName', 'Pieter Zeeman'), ('universityName', 'Leiden University'), ('uniloc', 'Leiden'), ('bloc', 'Zonnemaire')]
# [('personName', 'Pieter Zeeman'), ('universityName', 'Delft University of Technology'), ('uniloc', 'Delft'), ('bloc', 'Zonnemaire')]
# [('personName', 'Pieter Zeeman'), ('universityName', 'University of Amsterdam'), ('uniloc', 'Amsterdam'), ('bloc', 'Zonnemaire')]
# [('personName', 'Rainer Weiss'), ('universityName', 'Massachusetts Institute of Technology'), ('uniloc', 'Cambridge'), ('bloc', 'Berlin')]
# [('personName', 'Riccardo Giacconi'), ('universityName', 'Johns Hopkins University'), ('uniloc', 'Baltimore'), ('bloc', 'Genoa')]
# [('personName', 'Richard E. Taylor'), ('universityName', 'Stanford University'), ('uniloc', 'Stanford'), ('bloc', 'Medicine Hat')]
# [('personName', 'Richard Feynman'), ('universityName', 'California Institute of Technology'), ('uniloc', 'California'), ('bloc', 'Far Rockaway')]
# [('personName', 'Robert A. Millikan'), ('universityName', 'California Institute of Technology'), ('uniloc', 'California'), ('bloc', 'Morrison')]
# [('personName', 'Robert B. Laughlin'), ('universityName', 'Stanford University'), ('uniloc', 'Stanford'), ('bloc', 'Visalia')]
# [('personName', 'Robert Hofstadter'), ('universityName', 'Stanford University'), ('uniloc', 'Stanford'), ('bloc', 'New York City')]
# [('personName', 'Roger Penrose'), ('universityName', 'Leiden University'), ('uniloc', 'Leiden'), ('bloc', 'Colchester')]
# [('personName', 'Roy J. Glauber'), ('universityName', 'Leiden University'), ('uniloc', 'Leiden'), ('bloc', 'New York City')]
# [('personName', 'Rudolf Mössbauer'), ('universityName', 'California Institute of Technology'), ('uniloc', 'California'), ('bloc', 'Munich')]
# [('personName', 'Samuel C. C. Ting'), ('universityName', 'Massachusetts Institute of Technology'), ('uniloc', 'Cambridge'), ('bloc', 'Ann Arbor')]
# [('personName', 'Steven Chu'), ('universityName', 'Stanford University'), ('uniloc', 'Stanford'), ('bloc', 'St. Louis')]
# [('personName', 'Steven Weinberg'), ('universityName', 'Massachusetts Institute of Technology'), ('uniloc', 'Cambridge'), ('bloc', 'New York City')]
# [('personName', 'Theodor W. Hänsch'), ('universityName', 'Stanford University'), ('uniloc', 'Stanford'), ('bloc', 'Heidelberg')]
# [('personName', 'Theodor W. Hänsch'), ('universityName', 'University of Florence'), ('uniloc', 'Florence'), ('bloc', 'Heidelberg')]
# [('personName', 'Werner Heisenberg'), ('universityName', 'Leipzig University'), ('uniloc', 'Leipzig'), ('bloc', 'Würzburg')]
# [('personName', 'William Alfred Fowler'), ('universityName', 'California Institute of Technology'), ('uniloc', 'California'), ('bloc', 'Pittsburgh')]
# [('personName', 'William Shockley'), ('universityName', 'Stanford University'), ('uniloc', 'Stanford'), ('bloc', 'London')]
# [('personName', 'Wolfgang Ketterle'), ('universityName', 'Massachusetts Institute of Technology'), ('uniloc', 'Cambridge'), ('bloc', 'Heidelberg')]
# 103

# %%
#wdt:P106	occupation	predicate
#[('work', 'http://www.wikidata.org/entity/Q1622272'), ('workName', 'university teacher')]
#[('obj', 'http://www.wikidata.org/entity/Q7191'), ('objName', 'Nobel Prize')]
#I deleted the condition being a university teacher because when you apply this condition the query has no results 

#Final 
queryString = """
SELECT DISTINCT   ?person ?personName ?university ?universityName
WHERE {
    
    #being pysict
    # ?person wdt:P106 wd:Q169470.
    
    #winner of Nobel of pysics
    # ?person wdt:P166 wd:Q38104.
    
    #being university teacher 
    # ?person wdt:P106 wd:Q1622272.
    
     #persons BirthPlace 
    # ?person wdt:P19 ?birthPlace.
    
    #university employed 
    # ?person wdt:P108 ?university.
    # ?university wdt:P31 wd:Q3918.
    
    #university location 
    
    # ?university wdt:P159 ?uniLocation .
    
    
    
    #labels
    # ?person sc:name ?personName .
    # ?university sc:name ?universityName.
    # ?uniLocation sc:name ?u.
    # ?birthPlace sc:name ?b
    
    FILTER (?u=?b)

   
} 
"""
print("Results")
x=run_query(queryString)
# Out:
# Results
# Empty

# %% [markdown]
# Final query for this task

# %%
#wdt:P106	occupation	predicate
#[('work', 'http://www.wikidata.org/entity/Q1622272'), ('workName', 'university teacher')]
#[('obj', 'http://www.wikidata.org/entity/Q7191'), ('objName', 'Nobel Prize')]
#I deleted the condition being a university teacher because when you apply this condition the query has no results 

#Final 
queryString = """
SELECT DISTINCT   ?person ?personName ?university ?universityName
WHERE {
    
    #being pysict
    # ?person wdt:P106 wd:Q169470.
    
    #winner of Nobel of pysics
    # ?person wdt:P166 wd:Q38104.
    
    #being university teacher (DELETED BECAUSE WHEN ADD THIS CONDITION RETURNS NOTHING)
    #?person wdt:P106 wd:Q1622272.
    
     #persons BirthPlace 
    # ?person wdt:P19 ?birthPlace.
    
    #university employed 
    # ?person wdt:P108 ?university.
    # ?university wdt:P31 wd:Q3918.
    
    #university location 
    
    # ?university wdt:P159 ?uniLocation .
    
    
    
    #labels
    # ?person sc:name ?personName .
    # ?university sc:name ?universityName.
    # ?uniLocation sc:name ?u.
    # ?birthPlace sc:name ?b
    
    FILTER (?u=?b)

   
} 
"""
print("Results")
x=run_query(queryString)
# Out:
# Results
# [('person', 'http://www.wikidata.org/entity/Q202164'), ('personName', 'Makoto Kobayashi'), ('university', 'http://www.wikidata.org/entity/Q1191132'), ('universityName', 'Nagoya University')]
# [('person', 'http://www.wikidata.org/entity/Q9130'), ('personName', 'Erwin Schrödinger'), ('university', 'http://www.wikidata.org/entity/Q165980'), ('universityName', 'University of Vienna')]
# [('person', 'http://www.wikidata.org/entity/Q202168'), ('personName', 'Toshihide Maskawa'), ('university', 'http://www.wikidata.org/entity/Q1191132'), ('universityName', 'Nagoya University')]
# [('person', 'http://www.wikidata.org/entity/Q188128'), ('personName', 'Alexei Abrikosov'), ('university', 'http://www.wikidata.org/entity/Q4315005'), ('universityName', 'National University of Science and Technology')]
# [('person', 'http://www.wikidata.org/entity/Q188128'), ('personName', 'Alexei Abrikosov'), ('university', 'http://www.wikidata.org/entity/Q13164'), ('universityName', 'Moscow State University')]
# [('person', 'http://www.wikidata.org/entity/Q188128'), ('personName', 'Alexei Abrikosov'), ('university', 'http://www.wikidata.org/entity/Q1472245'), ('universityName', 'Bauman Moscow State Technical University')]
# 6

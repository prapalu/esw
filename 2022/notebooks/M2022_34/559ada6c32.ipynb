# %% [markdown]
# # General instructions
#
# The goal of the project is to materialize a set of **exploratory workloads** over a real-world, large-scale,  open-domain KG: [WikiData](https://www.wikidata.org/wiki/Wikidata:Main_Page)
#
# An exploratory workload  is composed by a set of queries, where each query is related to the information obtained previously.
#
# An exploratory workload starts with a usually vague, open ended question, and does not assume the person issuing the workload has a clear understanding of the data contained in the target database or its structure.
#
# Remeber that:
#
# 1. All the queries must run in the python notebook
# 2. You can use classes and properties only if you find them via a SPARQL query that must be present in the notebook
# 3. You do not delete useless queries. Keep everything that is synthatically valid
#
# ```
# ?p <http://schema.org/name> ?name .
# ```
#
#     is the BGP returning a human-readable name of a property or a class in Wikidata.

# %%
## SETUP used later

from SPARQLWrapper import SPARQLWrapper, JSON


prefixString = """
##-559ada6c32-##
PREFIX wd: <http://www.wikidata.org/entity/> 
PREFIX wdt: <http://www.wikidata.org/prop/direct/> 
PREFIX sc: <http://schema.org/>
"""

# select and construct queries
def run_query(queryString,verbose = True):
    to_run = prefixString + "\n" + queryString

    sparql = SPARQLWrapper("http://a256-gc1-03.srv.aau.dk:5820/sparql")
    sparql.setTimeout(300)
    sparql.setReturnFormat(JSON)
    sparql.setQuery(to_run)

    try :
        results = sparql.query()
        json_results = results.convert()
        if len(json_results['results']['bindings'])==0:
            print("Empty")
            return []
        array = []
        for bindings in json_results['results']['bindings']:
            app =  [ (var, value['value'])  for var, value in bindings.items() ] 
            if verbose:
                print( app)
            array.append(app)
        if verbose:
            print(len(array))
        return array

    except Exception as e :
        print("The operation failed", e)
    
# ASk queries
def run_ask_query(queryString):
    to_run = prefixString + "\n" + queryString

    sparql = SPARQLWrapper("http://a256-gc1-03.srv.aau.dk:5820/sparql")
    sparql.setTimeout(300)
    sparql.setReturnFormat(JSON)
    sparql.setQuery(to_run)

    try :
        return sparql.query().convert()

    except Exception as e :
        print("The operation failed", e)
# Out:
# The history saving thread hit an unexpected error (OperationalError('attempt to write a readonly database')).History will not be written to the database.

# %% [markdown]
# # History Workflow Series ("Cultural Movements explorative search")
#
# Consider the following exploratory information need:
#
# > investigate the cultural movements, in particular the Renaissance, Baroque and Romanticsm. We'd like to get an overview of the main artists belonging to these movements, musicians, poets, sculptors and painters.

# %% [markdown]
# ## Useful URIs for the current workflow
# The following are given:
#
# | IRI           | Description   | Role      |
# | -----------   | -----------   |-----------|
# | `wdt:P1647`   | subproperty   | predicate |
# | `wdt:P31`     | instance of   | predicate |
# | `wdt:P106`    | occupation    | predicate |
# | `wdt:P279`    | subclass      | predicate |
# | `wdt:P27`     | nationality   | predicate |
# | `wdt:P3342`     | Significant person       | predicate |
# | `wd:Q5`| Human       | node |
# | `wd:Q37562`| Donatello    | node |
# | `wd:Q19675`| Louvre Museum | node |

# %% [markdown]
# Also consider
#
# ```
# wd:Q37562 ?p ?obj .
# ```
#
# is the BGP to retrieve all **properties of Donatello**
#
# Please consider that when you return a resource, you should return the IRI and the label of the resource. In particular, when the task require you to identify a BGP the result set must always be a list of couples IRI - label.
#
# The workload should:
#
#
# 1. Identify the BGP for Cultural Movement
#
# 2. Identify the BGP for Renassaince, Baroque and Romanticism
#
# 3. Identify the BGP for composer, painter, sculptor and poet
#
# 4. Consider Renaissance, Baroque and Romanticism. Find how many composers, painters, sculptors and poets belong to those cultural movements (the results set must be a list of triples movement, job, #people)
#
# 5. Find how many sculptures were made in Italy during Renaissance, Baroque, and Romanticism movements. Please consider all the sculptures and all the sculpture subtypes. (the result set must be a list of triples movement IRI, label and #sculptures).
#
# 6. For each European country find how many poets belong to Romanticism (the result set must be a list of triples country IRI, label and #poets).
#
# 7. Find the number of sculptures in the Louvre Museum belonging to Renaissance, Baroque, or Romanticism (return a number for each movement) (the result set must be a list of triples movement IRI, label and #sculptures).

# %% [markdown]
# ## Task 1
# Identify the BGP for Cultural Movement

# %%
# query example
queryString = """
SELECT DISTINCT ?p ?name
WHERE {
   # bind something
   wd:Q37562 ?p ?obj .
   # get the label
   # ?p sc:name ?name.
}
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P1005'), ('name', 'Portuguese National Library ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1006'), ('name', 'Nationale Thesaurus voor Auteurs ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P101'), ('name', 'field of work')]
# [('p', 'http://www.wikidata.org/prop/direct/P1015'), ('name', 'NORAF ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1017'), ('name', 'Vatican Library ID (former scheme)')]
# [('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('p', 'http://www.wikidata.org/prop/direct/P1066'), ('name', 'student of')]
# [('p', 'http://www.wikidata.org/prop/direct/P1138'), ('name', 'Kunstindeks Danmark Artist ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P119'), ('name', 'place of burial')]
# [('p', 'http://www.wikidata.org/prop/direct/P1207'), ('name', 'NUKAT ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1248'), ('name', 'KulturNav-ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1263'), ('name', 'NNDB people ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1273'), ('name', 'CANTIC ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1280'), ('name', 'CONOR.SI ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1296'), ('name', 'Gran Enciclopèdia Catalana ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1315'), ('name', 'NLA Trove ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1343'), ('name', 'described by source')]
# [('p', 'http://www.wikidata.org/prop/direct/P135'), ('name', 'movement')]
# [('p', 'http://www.wikidata.org/prop/direct/P136'), ('name', 'genre')]
# [('p', 'http://www.wikidata.org/prop/direct/P1367'), ('name', 'Art UK artist ID')]
# 20

# %%
# query example
# [('p', 'http://www.wikidata.org/prop/direct/P135'), ('name', 'movement')]
queryString = """
SELECT DISTINCT ?p ?name
WHERE {
   # bind something
   wd:Q37562 wdt:P135 ?p .
   # get the label
   # ?p sc:name ?name.
}
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/entity/Q1472236'), ('name', 'Early Renaissance')]
# 1

# %%
# query example
# [('p', 'http://www.wikidata.org/prop/direct/P135'), ('name', 'movement')]
#[('p', 'http://www.wikidata.org/entity/Q1472236'), ('name', 'Early Renaissance')]
queryString = """
SELECT DISTINCT ?p ?name
WHERE {
   # bind something
   wd:Q1472236 ?p ?obj .
   # get the label
   # ?p sc:name ?name.
}
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P1014'), ('name', 'Art & Architecture Thesaurus ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1417'), ('name', 'Encyclopædia Britannica Online ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P155'), ('name', 'follows')]
# [('p', 'http://www.wikidata.org/prop/direct/P156'), ('name', 'followed by')]
# [('p', 'http://www.wikidata.org/prop/direct/P2347'), ('name', 'YSO ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2671'), ('name', 'Google Knowledge Graph ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('name', 'instance of')]
# [('p', 'http://www.wikidata.org/prop/direct/P361'), ('name', 'part of')]
# [('p', 'http://www.wikidata.org/prop/direct/P5604'), ('name', 'archINFORM keyword ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P571'), ('name', 'inception')]
# [('p', 'http://www.wikidata.org/prop/direct/P576'), ('name', 'dissolved, abolished or demolished date')]
# [('p', 'http://www.wikidata.org/prop/direct/P580'), ('name', 'start time')]
# [('p', 'http://www.wikidata.org/prop/direct/P582'), ('name', 'end time')]
# [('p', 'http://www.wikidata.org/prop/direct/P910'), ('name', "topic's main category")]
# 14

# %%
# query example
# [('p', 'http://www.wikidata.org/prop/direct/P135'), ('name', 'movement')]
#[('p', 'http://www.wikidata.org/entity/Q1472236'), ('name', 'Early Renaissance')]
#[('p', 'http://www.wikidata.org/prop/direct/P910'), ('name', "topic's main category")]
queryString = """
SELECT DISTINCT ?p ?name
WHERE {
   # bind something
   # ?p wdt:P910 ?o  .
   # get the label
   # ?p sc:name ?name.
   FILTER(REGEX(?name,"cultural movement"^^xsd:string))
}
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/entity/Q2198855'), ('name', 'cultural movement')]
# 1

# %%
# write your queries
# [('p', 'http://www.wikidata.org/prop/direct/P135'), ('name', 'movement')]
#[('p', 'http://www.wikidata.org/entity/Q1472236'), ('name', 'Early Renaissance')]
#[('p', 'http://www.wikidata.org/entity/Q4692'), ('name', 'Renaissance')]
queryString = """
SELECT DISTINCT ?p ?name
WHERE {
   # bind something
   wd:Q4692 ?obj ?p .
   # get the label
   # ?p sc:name ?name.
}
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/entity/Q13830551'), ('name', 'Portal:Renaissance')]
# [('p', 'http://www.wikidata.org/entity/Q15885248'), ('name', 'Renaissance painting')]
# [('p', 'http://www.wikidata.org/entity/Q1781608'), ('name', 'Renaissance literature')]
# [('p', 'http://www.wikidata.org/entity/Q1404472'), ('name', 'Italian Renaissance')]
# [('p', 'http://www.wikidata.org/entity/Q1472236'), ('name', 'Early Renaissance')]
# [('p', 'http://www.wikidata.org/entity/Q1474884'), ('name', 'High Renaissance')]
# [('p', 'http://www.wikidata.org/entity/Q2041543'), ('name', 'Ottův slovník naučný')]
# [('p', 'http://www.wikidata.org/entity/Q27496'), ('name', 'Western Europe')]
# [('p', 'http://www.wikidata.org/entity/Q3181656'), ('name', 'The Nuttall Encyclopædia')]
# [('p', 'http://www.wikidata.org/entity/Q37853'), ('name', 'Baroque')]
# [('p', 'http://www.wikidata.org/entity/Q5460604'), ('name', 'Wikipedia:Vital articles')]
# [('p', 'http://www.wikidata.org/entity/Q602358'), ('name', 'Brockhaus and Efron Encyclopedic Dictionary')]
# [('p', 'http://www.wikidata.org/entity/Q236122'), ('name', 'Renaissance architecture')]
# [('p', 'http://www.wikidata.org/entity/Q32880'), ('name', 'architectural style')]
# [('p', 'http://www.wikidata.org/entity/Q968159'), ('name', 'art movement')]
# [('p', 'http://www.wikidata.org/entity/Q12554'), ('name', 'Middle Ages')]
# [('p', 'http://www.wikidata.org/entity/Q201405'), ('name', 'Renaissance music')]
# [('p', 'http://www.wikidata.org/entity/Q2198855'), ('name', 'cultural movement')]
# [('p', 'http://www.wikidata.org/entity/Q46825'), ('name', 'Gothic art')]
# [('p', 'http://www.wikidata.org/entity/Q1133779'), ('name', 'Renaissance art')]
# 20

# %% [markdown]
# Final query for this task

# %%
# write your final query
# [('p', 'http://www.wikidata.org/prop/direct/P135'), ('name', 'movement')]
#[('p', 'http://www.wikidata.org/entity/Q1472236'), ('name', 'Early Renaissance')]
#[('p', 'http://www.wikidata.org/entity/Q4692'), ('name', 'Renaissance')]
#[('p', 'http://www.wikidata.org/entity/Q2198855'), ('name', 'cultural movement')]
queryString = """
SELECT DISTINCT ?p ?name
WHERE {
   # bind something
   wd:Q2198855 ?obj ?p .
   # get the label
   # ?p sc:name ?name.
}
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/entity/P135'), ('name', 'movement')]
# [('p', 'http://www.wikidata.org/entity/Q49773'), ('name', 'social movement')]
# [('p', 'http://www.wikidata.org/entity/Q3533467'), ('name', 'group action')]
# [('p', 'http://www.wikidata.org/entity/Q6638204'), ('name', 'Category:Cultural movement')]
# 4

# %% [markdown]
# ## Task 2
# Identify the BGP for Renassaince, Baroque and Romanticism

# %%
# write your queries
# [('p', 'http://www.wikidata.org/prop/direct/P135'), ('name', 'movement')]
#[('p', 'http://www.wikidata.org/entity/Q1472236'), ('name', 'Early Renaissance')]
queryString = """
SELECT DISTINCT ?p ?name
WHERE {
   # bind something
   wd:Q1472236 wdt:P361 ?p .
   # get the label
   # ?p sc:name ?name.
}
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/entity/Q4692'), ('name', 'Renaissance')]
# 1

# %%
# write your queries
# [('p', 'http://www.wikidata.org/prop/direct/P135'), ('name', 'movement')]
#[('p', 'http://www.wikidata.org/entity/Q1472236'), ('name', 'Early Renaissance')]
#[('p', 'http://www.wikidata.org/entity/Q4692'), ('name', 'Renaissance')]
queryString = """
SELECT DISTINCT ?p ?name
WHERE {
   # bind something
   wd:Q4692 ?obj ?p .
   # get the label
   # ?p sc:name ?name.
}
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/entity/Q13830551'), ('name', 'Portal:Renaissance')]
# [('p', 'http://www.wikidata.org/entity/Q15885248'), ('name', 'Renaissance painting')]
# [('p', 'http://www.wikidata.org/entity/Q1781608'), ('name', 'Renaissance literature')]
# [('p', 'http://www.wikidata.org/entity/Q1404472'), ('name', 'Italian Renaissance')]
# [('p', 'http://www.wikidata.org/entity/Q1472236'), ('name', 'Early Renaissance')]
# [('p', 'http://www.wikidata.org/entity/Q1474884'), ('name', 'High Renaissance')]
# [('p', 'http://www.wikidata.org/entity/Q2041543'), ('name', 'Ottův slovník naučný')]
# [('p', 'http://www.wikidata.org/entity/Q27496'), ('name', 'Western Europe')]
# [('p', 'http://www.wikidata.org/entity/Q3181656'), ('name', 'The Nuttall Encyclopædia')]
# [('p', 'http://www.wikidata.org/entity/Q37853'), ('name', 'Baroque')]
# [('p', 'http://www.wikidata.org/entity/Q5460604'), ('name', 'Wikipedia:Vital articles')]
# [('p', 'http://www.wikidata.org/entity/Q602358'), ('name', 'Brockhaus and Efron Encyclopedic Dictionary')]
# [('p', 'http://www.wikidata.org/entity/Q236122'), ('name', 'Renaissance architecture')]
# [('p', 'http://www.wikidata.org/entity/Q32880'), ('name', 'architectural style')]
# [('p', 'http://www.wikidata.org/entity/Q968159'), ('name', 'art movement')]
# [('p', 'http://www.wikidata.org/entity/Q12554'), ('name', 'Middle Ages')]
# [('p', 'http://www.wikidata.org/entity/Q201405'), ('name', 'Renaissance music')]
# [('p', 'http://www.wikidata.org/entity/Q2198855'), ('name', 'cultural movement')]
# [('p', 'http://www.wikidata.org/entity/Q46825'), ('name', 'Gothic art')]
# [('p', 'http://www.wikidata.org/entity/Q1133779'), ('name', 'Renaissance art')]
# 20

# %%
# write your queries
# [('p', 'http://www.wikidata.org/prop/direct/P135'), ('name', 'movement')]
#[('p', 'http://www.wikidata.org/entity/Q1472236'), ('name', 'Early Renaissance')]
#[('p', 'http://www.wikidata.org/entity/Q4692'), ('name', 'Renaissance')]
#[('p', 'http://www.wikidata.org/entity/Q37853'), ('name', 'Baroque')]
queryString = """
SELECT DISTINCT  ?o ?bname
WHERE {
   # bind something
  # wd:Q4692 ?obj ?p .
   wd:Q37853 ?obj1 ?o.
   # get the label
   #?p sc:name ?name.
   # ?o sc:name ?bname.
}
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('o', 'http://www.wikidata.org/entity/Q172991'), ('bname', 'Council of Trent')]
# [('o', 'http://www.wikidata.org/entity/Q11514315'), ('bname', 'historical period')]
# [('o', 'http://www.wikidata.org/entity/Q1292119'), ('bname', 'style')]
# [('o', 'http://www.wikidata.org/entity/Q131808'), ('bname', 'Mannerism')]
# [('o', 'http://www.wikidata.org/entity/Q2041543'), ('bname', 'Ottův slovník naučný')]
# [('o', 'http://www.wikidata.org/entity/Q2657718'), ('bname', 'Armenian Soviet Encyclopedia')]
# [('o', 'http://www.wikidata.org/entity/Q3181656'), ('bname', 'The Nuttall Encyclopædia')]
# [('o', 'http://www.wikidata.org/entity/Q32880'), ('bname', 'architectural style')]
# [('o', 'http://www.wikidata.org/entity/Q4692'), ('bname', 'Renaissance')]
# [('o', 'http://www.wikidata.org/entity/Q968159'), ('bname', 'art movement')]
# [('o', 'http://www.wikidata.org/entity/Q2198855'), ('bname', 'cultural movement')]
# [('o', 'http://www.wikidata.org/entity/Q1431376'), ('bname', 'Baroque literature')]
# [('o', 'http://www.wikidata.org/entity/Q3624106'), ('bname', 'Baroque art')]
# [('o', 'http://www.wikidata.org/entity/Q63442026'), ('bname', 'High Baroque')]
# [('o', 'http://www.wikidata.org/entity/Q8810374'), ('bname', 'Category:Baroque')]
# 15

# %%
# write your final query
# [('p', 'http://www.wikidata.org/prop/direct/P135'), ('name', 'movement')]
#[('p', 'http://www.wikidata.org/entity/Q1472236'), ('name', 'Early Renaissance')]
#[('p', 'http://www.wikidata.org/entity/Q4692'), ('name', 'Renaissance')]
#[('p', 'http://www.wikidata.org/entity/Q2198855'), ('name', 'cultural movement')]
queryString = """
SELECT DISTINCT ?p ?name
WHERE {
   # bind something
    # ?p wdt:P31 wd:Q2198855.
    #wd:Q2198855 ?obj ?p.
   # get the label
   # ?p sc:name ?name.
}
LIMIT 200
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/entity/Q8210150'), ('name', 'Avanzada Regia')]
# [('p', 'http://www.wikidata.org/entity/Q211481'), ('name', 'Dogme 95')]
# [('p', 'http://www.wikidata.org/entity/Q2046861'), ('name', 'Palaeologan Renaissance')]
# [('p', 'http://www.wikidata.org/entity/Q1400430'), ('name', 'Macedonian Renaissance')]
# [('p', 'http://www.wikidata.org/entity/Q430167'), ('name', 'Spanish Renaissance')]
# [('p', 'http://www.wikidata.org/entity/Q1814286'), ('name', 'Young Estonia')]
# [('p', 'http://www.wikidata.org/entity/Q2614483'), ('name', 'Pre-romanticism')]
# [('p', 'http://www.wikidata.org/entity/Q39427'), ('name', 'surrealism')]
# [('p', 'http://www.wikidata.org/entity/Q2349908'), ('name', 'French Renaissance')]
# [('p', 'http://www.wikidata.org/entity/Q878985'), ('name', 'modernism')]
# [('p', 'http://www.wikidata.org/entity/Q466887'), ('name', 'Belle Époque')]
# [('p', 'http://www.wikidata.org/entity/Q12539'), ('name', 'Age of Enlightenment')]
# [('p', 'http://www.wikidata.org/entity/Q265581'), ('name', 'fin de siècle')]
# [('p', 'http://www.wikidata.org/entity/Q42865'), ('name', 'Orientalism')]
# [('p', 'http://www.wikidata.org/entity/Q934618'), ('name', 'Danish Golden Age')]
# [('p', 'http://www.wikidata.org/entity/Q3488076'), ('name', 'La Sape')]
# [('p', 'http://www.wikidata.org/entity/Q3083331'), ('name', 'Andean Baroque')]
# [('p', 'http://www.wikidata.org/entity/Q1753636'), ('name', 'Gilded Age')]
# [('p', 'http://www.wikidata.org/entity/Q131808'), ('name', 'Mannerism')]
# [('p', 'http://www.wikidata.org/entity/Q1404472'), ('name', 'Italian Renaissance')]
# [('p', 'http://www.wikidata.org/entity/Q37068'), ('name', 'Romanticism')]
# [('p', 'http://www.wikidata.org/entity/Q37853'), ('name', 'Baroque')]
# [('p', 'http://www.wikidata.org/entity/Q751880'), ('name', 'japonism')]
# [('p', 'http://www.wikidata.org/entity/Q620629'), ('name', 'deism')]
# [('p', 'http://www.wikidata.org/entity/Q4692'), ('name', 'Renaissance')]
# [('p', 'http://www.wikidata.org/entity/Q744738'), ('name', 'encyclopédistes')]
# [('p', 'http://www.wikidata.org/entity/Q863679'), ('name', 'chinoiserie')]
# [('p', 'http://www.wikidata.org/entity/Q4745501'), ('name', 'American modernism')]
# [('p', 'http://www.wikidata.org/entity/Q164800'), ('name', 'Symbolism')]
# [('p', 'http://www.wikidata.org/entity/Q5653011'), ('name', 'North Group')]
# [('p', 'http://www.wikidata.org/entity/Q6034'), ('name', 'Dada')]
# [('p', 'http://www.wikidata.org/entity/Q466521'), ('name', 'kinetic art')]
# [('p', 'http://www.wikidata.org/entity/Q374278'), ('name', 'agitprop')]
# [('p', 'http://www.wikidata.org/entity/Q940595'), ('name', 'Zutiste')]
# [('p', 'http://www.wikidata.org/entity/Q2896922'), ('name', 'Berberism')]
# [('p', 'http://www.wikidata.org/entity/Q846933'), ('name', 'renaissance humanism')]
# [('p', 'http://www.wikidata.org/entity/Q194100'), ('name', 'transhumanism')]
# [('p', 'http://www.wikidata.org/entity/Q9033935'), ('name', 'Brazilian modernism')]
# [('p', 'http://www.wikidata.org/entity/Q2390991'), ('name', 'Gothicismus')]
# [('p', 'http://www.wikidata.org/entity/Q1347824'), ('name', 'La Movida Madrileña')]
# [('p', 'http://www.wikidata.org/entity/Q3424747'), ('name', 'Modern Greek Enlightenment')]
# [('p', 'http://www.wikidata.org/entity/Q3482195'), ('name', 'shingeki')]
# [('p', 'http://www.wikidata.org/entity/Q472670'), ('name', 'Haskalah')]
# [('p', 'http://www.wikidata.org/entity/Q64528910'), ('name', 'The Forge')]
# [('p', 'http://www.wikidata.org/entity/Q3362516'), ('name', 'Afrofuturism')]
# [('p', 'http://www.wikidata.org/entity/Q1759189'), ('name', 'mangue bit')]
# [('p', 'http://www.wikidata.org/entity/Q10468834'), ('name', 'White cube gallery')]
# [('p', 'http://www.wikidata.org/entity/Q89099707'), ('name', 'Özgün müzik')]
# [('p', 'http://www.wikidata.org/entity/Q478004'), ('name', 'anti-clericalism')]
# [('p', 'http://www.wikidata.org/entity/Q10936092'), ('name', 'Taisho Roman')]
# [('p', 'http://www.wikidata.org/entity/Q1580216'), ('name', 'Noucentisme')]
# [('p', 'http://www.wikidata.org/entity/Q160476'), ('name', 'German Expressionism')]
# [('p', 'http://www.wikidata.org/entity/Q2639653'), ('name', 'Leonese regionalism')]
# [('p', 'http://www.wikidata.org/entity/Q64761829'), ('name', 'New Drama')]
# [('p', 'http://www.wikidata.org/entity/Q15991289'), ('name', 'Old School Renaissance')]
# [('p', 'http://www.wikidata.org/entity/Q16573056'), ('name', 'Guardia Vieja')]
# [('p', 'http://www.wikidata.org/entity/Q3298288'), ('name', 'post-postmodernism')]
# [('p', 'http://www.wikidata.org/entity/Q1133329'), ('name', 'Young Poland')]
# [('p', 'http://www.wikidata.org/entity/Q979160'), ('name', 'Proto-Renaissance')]
# [('p', 'http://www.wikidata.org/entity/Q1172762'), ('name', 'Dau al Set')]
# [('p', 'http://www.wikidata.org/entity/Q2907232'), ('name', 'Antropophagia')]
# [('p', 'http://www.wikidata.org/entity/Q4920294'), ('name', 'Black Arts Movement')]
# [('p', 'http://www.wikidata.org/entity/Q153946'), ('name', 'punk counterculture')]
# [('p', 'http://www.wikidata.org/entity/Q6110311'), ('name', 'flamenco rock')]
# [('p', 'http://www.wikidata.org/entity/Q1413061'), ('name', 'tropicália')]
# [('p', 'http://www.wikidata.org/entity/Q7215510'), ('name', 'Ukrainian Russophiles')]
# [('p', 'http://www.wikidata.org/entity/Q2368408'), ('name', 'artistic indianism')]
# [('p', 'http://www.wikidata.org/entity/Q703472'), ('name', 'Renaixença')]
# [('p', 'http://www.wikidata.org/entity/Q16497571'), ('name', 'Brazilian Belle Époque')]
# [('p', 'http://www.wikidata.org/entity/Q1745141'), ('name', 'Fantastic Realism')]
# [('p', 'http://www.wikidata.org/entity/Q61693382'), ('name', 'pilantragem')]
# [('p', 'http://www.wikidata.org/entity/Q852377'), ('name', 'New Culture Movement')]
# [('p', 'http://www.wikidata.org/entity/Q63442026'), ('name', 'High Baroque')]
# [('p', 'http://www.wikidata.org/entity/Q899271'), ('name', 'Baroque in Brazil')]
# [('p', 'http://www.wikidata.org/entity/Q4922353'), ('name', 'Black is Beautiful')]
# [('p', 'http://www.wikidata.org/entity/Q1431758'), ('name', 'San Francisco Renaissance')]
# [('p', 'http://www.wikidata.org/entity/Q1520921'), ('name', 'Nahda')]
# [('p', 'http://www.wikidata.org/entity/Q2289148'), ('name', 'The Singing Voice of Germany')]
# [('p', 'http://www.wikidata.org/entity/Q877637'), ('name', 'Rangaku')]
# [('p', 'http://www.wikidata.org/entity/Q3683985'), ('name', 'combat folk')]
# [('p', 'http://www.wikidata.org/entity/Q234105'), ('name', 'Lost Generation')]
# [('p', 'http://www.wikidata.org/entity/Q5651123'), ('name', 'Hanshinkan Modernism')]
# [('p', 'http://www.wikidata.org/entity/Q57206373'), ('name', 'Black Aesthetic')]
# [('p', 'http://www.wikidata.org/entity/Q1713406'), ('name', 'Young Germany')]
# [('p', 'http://www.wikidata.org/entity/Q700923'), ('name', 'Vormärz')]
# [('p', 'http://www.wikidata.org/entity/Q3326886'), ('name', 'Ez Dok Amairu')]
# [('p', 'http://www.wikidata.org/entity/Q2037910'), ('name', 'Swinging London')]
# [('p', 'http://www.wikidata.org/entity/Q8059379'), ('name', 'Youthquake')]
# [('p', 'http://www.wikidata.org/entity/Q74950'), ('name', 'objectivism')]
# [('p', 'http://www.wikidata.org/entity/Q856643'), ('name', 'Trecento')]
# [('p', 'http://www.wikidata.org/entity/Q105661166'), ('name', 'Tutmania')]
# [('p', 'http://www.wikidata.org/entity/Q254272'), ('name', 'Egyptomania')]
# [('p', 'http://www.wikidata.org/entity/Q700324'), ('name', 'Bunmei Kaika')]
# [('p', 'http://www.wikidata.org/entity/Q1334000'), ('name', 'School of Salamanca')]
# [('p', 'http://www.wikidata.org/entity/Q3307647'), ('name', 'Rexurdimento')]
# [('p', 'http://www.wikidata.org/entity/Q104215395'), ('name', 'Africanfuturism')]
# [('p', 'http://www.wikidata.org/entity/Q3953335'), ('name', 'Genoa school')]
# [('p', 'http://www.wikidata.org/entity/Q6025377'), ('name', 'Movimiento indaliano')]
# [('p', 'http://www.wikidata.org/entity/Q3759612'), ('name', 'Generation of 1914')]
# [('p', 'http://www.wikidata.org/entity/Q695274'), ('name', 'Philhellenism')]
# [('p', 'http://www.wikidata.org/entity/Q2717024'), ('name', 'Pre-Pottery Neolithic C')]
# [('p', 'http://www.wikidata.org/entity/Q3547880'), ('name', 'ukiyo')]
# [('p', 'http://www.wikidata.org/entity/Q3718891'), ('name', 'Silver Age')]
# [('p', 'http://www.wikidata.org/entity/Q85758112'), ('name', 'e-girls and e-boys')]
# [('p', 'http://www.wikidata.org/entity/Q3441123'), ('name', 'Romantisme baroque')]
# [('p', 'http://www.wikidata.org/entity/Q88467256'), ('name', 'Asturian Baroque')]
# [('p', 'http://www.wikidata.org/entity/Q11838999'), ('name', 'The Flacăra cenacle')]
# [('p', 'http://www.wikidata.org/entity/Q694408'), ('name', 'Weimar Classicism')]
# [('p', 'http://www.wikidata.org/entity/Q1263842'), ('name', 'Duecento')]
# [('p', 'http://www.wikidata.org/entity/Q12179231'), ('name', 'Pre-Islamic literature')]
# [('p', 'http://www.wikidata.org/entity/Q6296743'), ('name', 'Jovem Guarda')]
# [('p', 'http://www.wikidata.org/entity/Q336522'), ('name', 'Indie role-playing game')]
# [('p', 'http://www.wikidata.org/entity/Q42907814'), ('name', 'dandyism')]
# [('p', 'http://www.wikidata.org/entity/Q969107'), ('name', 'postgenderism')]
# [('p', 'http://www.wikidata.org/entity/Q57244244'), ('name', 'Black Atlantic')]
# [('p', 'http://www.wikidata.org/entity/Q329170'), ('name', 'Wissenschaft des Judentums')]
# [('p', 'http://www.wikidata.org/entity/Q700429'), ('name', 'Wiener Moderne')]
# [('p', 'http://www.wikidata.org/entity/Q1755539'), ('name', 'City Beautiful movement')]
# [('p', 'http://www.wikidata.org/entity/Q3866622'), ('name', 'Movimento di Cooperazione Educativa')]
# [('p', 'http://www.wikidata.org/entity/Q5421149'), ('name', 'experimental architecture')]
# [('p', 'http://www.wikidata.org/entity/Q1061960'), ('name', 'Purismo')]
# [('p', 'http://www.wikidata.org/entity/Q3935973'), ('name', 'Renaissance in Ferrara')]
# [('p', 'http://www.wikidata.org/entity/Q85850403'), ('name', 'Convergence culture')]
# [('p', 'http://www.wikidata.org/entity/Q5528642'), ('name', 'Gay Shame')]
# [('p', 'http://www.wikidata.org/entity/Q239514'), ('name', 'Quiet Revolution')]
# [('p', 'http://www.wikidata.org/entity/Q5443468'), ('name', 'Aetas Ovidiana')]
# [('p', 'http://www.wikidata.org/entity/Q85148248'), ('name', 'Thullal prasthanam')]
# [('p', 'http://www.wikidata.org/entity/Q3575095'), ('name', 'Zef')]
# [('p', 'http://www.wikidata.org/entity/Q131826'), ('name', 'Young Latvians')]
# [('p', 'http://www.wikidata.org/entity/Q4120724'), ('name', 'Ōuchi culture')]
# [('p', 'http://www.wikidata.org/entity/Q672638'), ('name', 'spiritual defence')]
# [('p', 'http://www.wikidata.org/entity/Q11937152'), ('name', 'Modernism in Camprodon')]
# [('p', 'http://www.wikidata.org/entity/Q16488690'), ('name', 'Armenian Renaissance')]
# [('p', 'http://www.wikidata.org/entity/Q5669970'), ('name', 'Movida viguesa')]
# [('p', 'http://www.wikidata.org/entity/Q31358818'), ('name', 'Cool Cymru')]
# [('p', 'http://www.wikidata.org/entity/Q7269008'), ('name', 'Quantum aesthetics')]
# [('p', 'http://www.wikidata.org/entity/Q1793969'), ('name', 'Scandinavian design')]
# [('p', 'http://www.wikidata.org/entity/Q4789421'), ('name', 'Argentine Open Theatre')]
# 138

# %%
#[('p', 'http://www.wikidata.org/entity/Q37068'), ('name', 'Romanticism')]
#[('p', 'http://www.wikidata.org/entity/Q37853'), ('name', 'Baroque')]
#[('p', 'http://www.wikidata.org/entity/Q4692'), ('name', 'Renaissance')]
queryString = """
SELECT DISTINCT ?roman ?rname ?bar ?bname ?rena ?ename 
WHERE {
   # bind something
    wd:Q37068 ?obj ?roman.
    wd:Q37853 ?obj1 ?bar.
    wd:Q4692 ?obj2 ?rena.
   # get the label
   # ?roman sc:name ?rname.
   # ?bar sc:name ?bname.
   # ?rena sc:name ?ename.
}
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('roman', 'http://www.wikidata.org/entity/Q2614483'), ('rname', 'Pre-romanticism'), ('bar', 'http://www.wikidata.org/entity/Q2041543'), ('bname', 'Ottův slovník naučný'), ('rena', 'http://www.wikidata.org/entity/Q12554'), ('ename', 'Middle Ages')]
# [('roman', 'http://www.wikidata.org/entity/Q2614483'), ('rname', 'Pre-romanticism'), ('bar', 'http://www.wikidata.org/entity/Q2041543'), ('bname', 'Ottův slovník naučný'), ('rena', 'http://www.wikidata.org/entity/Q27496'), ('ename', 'Western Europe')]
# [('roman', 'http://www.wikidata.org/entity/Q2614483'), ('rname', 'Pre-romanticism'), ('bar', 'http://www.wikidata.org/entity/Q2041543'), ('bname', 'Ottův slovník naučný'), ('rena', 'http://www.wikidata.org/entity/Q979160'), ('ename', 'Proto-Renaissance')]
# [('roman', 'http://www.wikidata.org/entity/Q2614483'), ('rname', 'Pre-romanticism'), ('bar', 'http://www.wikidata.org/entity/Q2041543'), ('bname', 'Ottův slovník naučný'), ('rena', 'http://www.wikidata.org/entity/Q1404472'), ('ename', 'Italian Renaissance')]
# [('roman', 'http://www.wikidata.org/entity/Q2614483'), ('rname', 'Pre-romanticism'), ('bar', 'http://www.wikidata.org/entity/Q2041543'), ('bname', 'Ottův slovník naučný'), ('rena', 'http://www.wikidata.org/entity/Q1133779'), ('ename', 'Renaissance art')]
# [('roman', 'http://www.wikidata.org/entity/Q2614483'), ('rname', 'Pre-romanticism'), ('bar', 'http://www.wikidata.org/entity/Q2041543'), ('bname', 'Ottův slovník naučný'), ('rena', 'http://www.wikidata.org/entity/Q7112776'), ('ename', 'outline of the Renaissance')]
# [('roman', 'http://www.wikidata.org/entity/Q2614483'), ('rname', 'Pre-romanticism'), ('bar', 'http://www.wikidata.org/entity/Q2041543'), ('bname', 'Ottův slovník naučný'), ('rena', 'http://www.wikidata.org/entity/Q602358'), ('ename', 'Brockhaus and Efron Encyclopedic Dictionary')]
# [('roman', 'http://www.wikidata.org/entity/Q2614483'), ('rname', 'Pre-romanticism'), ('bar', 'http://www.wikidata.org/entity/Q2657718'), ('bname', 'Armenian Soviet Encyclopedia'), ('rena', 'http://www.wikidata.org/entity/Q12554'), ('ename', 'Middle Ages')]
# [('roman', 'http://www.wikidata.org/entity/Q2614483'), ('rname', 'Pre-romanticism'), ('bar', 'http://www.wikidata.org/entity/Q2657718'), ('bname', 'Armenian Soviet Encyclopedia'), ('rena', 'http://www.wikidata.org/entity/Q27496'), ('ename', 'Western Europe')]
# [('roman', 'http://www.wikidata.org/entity/Q2614483'), ('rname', 'Pre-romanticism'), ('bar', 'http://www.wikidata.org/entity/Q2657718'), ('bname', 'Armenian Soviet Encyclopedia'), ('rena', 'http://www.wikidata.org/entity/Q979160'), ('ename', 'Proto-Renaissance')]
# [('roman', 'http://www.wikidata.org/entity/Q2614483'), ('rname', 'Pre-romanticism'), ('bar', 'http://www.wikidata.org/entity/Q2657718'), ('bname', 'Armenian Soviet Encyclopedia'), ('rena', 'http://www.wikidata.org/entity/Q1404472'), ('ename', 'Italian Renaissance')]
# [('roman', 'http://www.wikidata.org/entity/Q2614483'), ('rname', 'Pre-romanticism'), ('bar', 'http://www.wikidata.org/entity/Q2657718'), ('bname', 'Armenian Soviet Encyclopedia'), ('rena', 'http://www.wikidata.org/entity/Q1133779'), ('ename', 'Renaissance art')]
# [('roman', 'http://www.wikidata.org/entity/Q2614483'), ('rname', 'Pre-romanticism'), ('bar', 'http://www.wikidata.org/entity/Q2657718'), ('bname', 'Armenian Soviet Encyclopedia'), ('rena', 'http://www.wikidata.org/entity/Q7112776'), ('ename', 'outline of the Renaissance')]
# [('roman', 'http://www.wikidata.org/entity/Q2614483'), ('rname', 'Pre-romanticism'), ('bar', 'http://www.wikidata.org/entity/Q2657718'), ('bname', 'Armenian Soviet Encyclopedia'), ('rena', 'http://www.wikidata.org/entity/Q602358'), ('ename', 'Brockhaus and Efron Encyclopedic Dictionary')]
# [('roman', 'http://www.wikidata.org/entity/Q2614483'), ('rname', 'Pre-romanticism'), ('bar', 'http://www.wikidata.org/entity/Q3181656'), ('bname', 'The Nuttall Encyclopædia'), ('rena', 'http://www.wikidata.org/entity/Q12554'), ('ename', 'Middle Ages')]
# [('roman', 'http://www.wikidata.org/entity/Q2614483'), ('rname', 'Pre-romanticism'), ('bar', 'http://www.wikidata.org/entity/Q3181656'), ('bname', 'The Nuttall Encyclopædia'), ('rena', 'http://www.wikidata.org/entity/Q27496'), ('ename', 'Western Europe')]
# [('roman', 'http://www.wikidata.org/entity/Q2614483'), ('rname', 'Pre-romanticism'), ('bar', 'http://www.wikidata.org/entity/Q3181656'), ('bname', 'The Nuttall Encyclopædia'), ('rena', 'http://www.wikidata.org/entity/Q979160'), ('ename', 'Proto-Renaissance')]
# [('roman', 'http://www.wikidata.org/entity/Q2614483'), ('rname', 'Pre-romanticism'), ('bar', 'http://www.wikidata.org/entity/Q3181656'), ('bname', 'The Nuttall Encyclopædia'), ('rena', 'http://www.wikidata.org/entity/Q1404472'), ('ename', 'Italian Renaissance')]
# [('roman', 'http://www.wikidata.org/entity/Q2614483'), ('rname', 'Pre-romanticism'), ('bar', 'http://www.wikidata.org/entity/Q3181656'), ('bname', 'The Nuttall Encyclopædia'), ('rena', 'http://www.wikidata.org/entity/Q1133779'), ('ename', 'Renaissance art')]
# [('roman', 'http://www.wikidata.org/entity/Q2614483'), ('rname', 'Pre-romanticism'), ('bar', 'http://www.wikidata.org/entity/Q3181656'), ('bname', 'The Nuttall Encyclopædia'), ('rena', 'http://www.wikidata.org/entity/Q7112776'), ('ename', 'outline of the Renaissance')]
# 20

# %% [markdown]
# Final query for this task

# %%
# write your final query
#[('p', 'http://www.wikidata.org/entity/Q37068'), ('name', 'Romanticism')]
#[('p', 'http://www.wikidata.org/entity/Q37853'), ('name', 'Baroque')]
#[('p', 'http://www.wikidata.org/entity/Q4692'), ('name', 'Renaissance')]
queryString = """
SELECT DISTINCT ?roman ?rname ?bar ?bname ?rena ?ename 
WHERE {
    {
    wd:Q37068 ?roman ?obj.
    # ?roman sc:name ?rname.
    }
    UNION
    {
    wd:Q37853 ?bar ?obj1.
    # ?bar sc:name ?bname.
    }
    UNION 
    {
    wd:Q4692 ?rena ?obj2.
    # ?rena sc:name ?ename.
   }
   
   
}
LIMIT 200
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('roman', 'http://www.wikidata.org/prop/direct/P1014'), ('rname', 'Art & Architecture Thesaurus ID')]
# [('roman', 'http://www.wikidata.org/prop/direct/P1036'), ('rname', 'Dewey Decimal Classification')]
# [('roman', 'http://www.wikidata.org/prop/direct/P1051'), ('rname', 'PSH ID')]
# [('roman', 'http://www.wikidata.org/prop/direct/P1245'), ('rname', 'OmegaWiki Defined Meaning')]
# [('roman', 'http://www.wikidata.org/prop/direct/P1296'), ('rname', 'Gran Enciclopèdia Catalana ID')]
# [('roman', 'http://www.wikidata.org/prop/direct/P1343'), ('rname', 'described by source')]
# [('roman', 'http://www.wikidata.org/prop/direct/P1417'), ('rname', 'Encyclopædia Britannica Online ID')]
# [('roman', 'http://www.wikidata.org/prop/direct/P155'), ('rname', 'follows')]
# [('roman', 'http://www.wikidata.org/prop/direct/P156'), ('rname', 'followed by')]
# [('roman', 'http://www.wikidata.org/prop/direct/P18'), ('rname', 'image')]
# [('roman', 'http://www.wikidata.org/prop/direct/P1807'), ('rname', 'Great Aragonese Encyclopedia ID')]
# [('roman', 'http://www.wikidata.org/prop/direct/P227'), ('rname', 'GND ID')]
# [('roman', 'http://www.wikidata.org/prop/direct/P2347'), ('rname', 'YSO ID')]
# [('roman', 'http://www.wikidata.org/prop/direct/P244'), ('rname', 'Library of Congress authority ID')]
# [('roman', 'http://www.wikidata.org/prop/direct/P2581'), ('rname', 'BabelNet ID')]
# [('roman', 'http://www.wikidata.org/prop/direct/P268'), ('rname', 'Bibliothèque nationale de France ID')]
# [('roman', 'http://www.wikidata.org/prop/direct/P2924'), ('rname', 'Great Russian Encyclopedia Online ID')]
# [('roman', 'http://www.wikidata.org/prop/direct/P2959'), ('rname', 'permanent duplicated item')]
# [('roman', 'http://www.wikidata.org/prop/direct/P31'), ('rname', 'instance of')]
# [('roman', 'http://www.wikidata.org/prop/direct/P3219'), ('rname', 'Encyclopædia Universalis ID')]
# [('roman', 'http://www.wikidata.org/prop/direct/P3222'), ('rname', 'NE.se ID')]
# [('roman', 'http://www.wikidata.org/prop/direct/P3235'), ('rname', 'PhilPapers topic')]
# [('roman', 'http://www.wikidata.org/prop/direct/P3365'), ('rname', 'Treccani ID')]
# [('roman', 'http://www.wikidata.org/prop/direct/P3417'), ('rname', 'Quora topic ID')]
# [('roman', 'http://www.wikidata.org/prop/direct/P349'), ('rname', 'National Diet Library ID')]
# [('roman', 'http://www.wikidata.org/prop/direct/P3553'), ('rname', 'Zhihu topic ID')]
# [('roman', 'http://www.wikidata.org/prop/direct/P373'), ('rname', 'Commons category')]
# [('roman', 'http://www.wikidata.org/prop/direct/P3827'), ('rname', 'JSTOR topic ID')]
# [('roman', 'http://www.wikidata.org/prop/direct/P4223'), ('rname', "Treccani's Enciclopedia Italiana ID")]
# [('roman', 'http://www.wikidata.org/prop/direct/P443'), ('rname', 'pronunciation audio')]
# [('roman', 'http://www.wikidata.org/prop/direct/P486'), ('rname', 'MeSH descriptor ID')]
# [('roman', 'http://www.wikidata.org/prop/direct/P508'), ('rname', 'BNCF Thesaurus ID')]
# [('roman', 'http://www.wikidata.org/prop/direct/P527'), ('rname', 'has part')]
# [('roman', 'http://www.wikidata.org/prop/direct/P571'), ('rname', 'inception')]
# [('roman', 'http://www.wikidata.org/prop/direct/P580'), ('rname', 'start time')]
# [('roman', 'http://www.wikidata.org/prop/direct/P582'), ('rname', 'end time')]
# [('roman', 'http://www.wikidata.org/prop/direct/P6058'), ('rname', 'Larousse ID')]
# [('roman', 'http://www.wikidata.org/prop/direct/P6366'), ('rname', 'Microsoft Academic ID')]
# [('roman', 'http://www.wikidata.org/prop/direct/P6404'), ('rname', "Treccani's Dizionario di Storia ID")]
# [('roman', 'http://www.wikidata.org/prop/direct/P646'), ('rname', 'Freebase ID')]
# [('roman', 'http://www.wikidata.org/prop/direct/P6573'), ('rname', 'Klexikon article ID')]
# [('roman', 'http://www.wikidata.org/prop/direct/P7033'), ('rname', 'Australian Educational Vocabulary ID')]
# [('roman', 'http://www.wikidata.org/prop/direct/P7786'), ('rname', 'Joconde epoch ID')]
# [('roman', 'http://www.wikidata.org/prop/direct/P7818'), ('rname', 'French Vikidia ID')]
# [('roman', 'http://www.wikidata.org/prop/direct/P7832'), ('rname', 'Basque Vikidia ID')]
# [('roman', 'http://www.wikidata.org/prop/direct/P7993'), ('rname', "Treccani's Dizionario di Filosofia ID")]
# [('roman', 'http://www.wikidata.org/prop/direct/P8168'), ('rname', 'FactGrid item ID')]
# [('roman', 'http://www.wikidata.org/prop/direct/P8406'), ('rname', 'Grove Art Online ID')]
# [('roman', 'http://www.wikidata.org/prop/direct/P8408'), ('rname', 'KBpedia ID')]
# [('roman', 'http://www.wikidata.org/prop/direct/P9070'), ('rname', 'Internet Encyclopedia of Ukraine ID')]
# [('roman', 'http://www.wikidata.org/prop/direct/P910'), ('rname', "topic's main category")]
# [('roman', 'http://www.wikidata.org/prop/direct/P935'), ('rname', 'Commons gallery')]
# [('roman', 'http://www.wikidata.org/prop/direct/P950'), ('rname', 'Biblioteca Nacional de España ID')]
# [('bar', 'http://www.wikidata.org/prop/direct/P1014'), ('bname', 'Art & Architecture Thesaurus ID')]
# [('bar', 'http://www.wikidata.org/prop/direct/P1051'), ('bname', 'PSH ID')]
# [('bar', 'http://www.wikidata.org/prop/direct/P1245'), ('bname', 'OmegaWiki Defined Meaning')]
# [('bar', 'http://www.wikidata.org/prop/direct/P1296'), ('bname', 'Gran Enciclopèdia Catalana ID')]
# [('bar', 'http://www.wikidata.org/prop/direct/P1343'), ('bname', 'described by source')]
# [('bar', 'http://www.wikidata.org/prop/direct/P1417'), ('bname', 'Encyclopædia Britannica Online ID')]
# [('bar', 'http://www.wikidata.org/prop/direct/P155'), ('bname', 'follows')]
# [('bar', 'http://www.wikidata.org/prop/direct/P18'), ('bname', 'image')]
# [('bar', 'http://www.wikidata.org/prop/direct/P1807'), ('bname', 'Great Aragonese Encyclopedia ID')]
# [('bar', 'http://www.wikidata.org/prop/direct/P227'), ('bname', 'GND ID')]
# [('bar', 'http://www.wikidata.org/prop/direct/P2347'), ('bname', 'YSO ID')]
# [('bar', 'http://www.wikidata.org/prop/direct/P244'), ('bname', 'Library of Congress authority ID')]
# [('bar', 'http://www.wikidata.org/prop/direct/P2581'), ('bname', 'BabelNet ID')]
# [('bar', 'http://www.wikidata.org/prop/direct/P268'), ('bname', 'Bibliothèque nationale de France ID')]
# [('bar', 'http://www.wikidata.org/prop/direct/P2924'), ('bname', 'Great Russian Encyclopedia Online ID')]
# [('bar', 'http://www.wikidata.org/prop/direct/P31'), ('bname', 'instance of')]
# [('bar', 'http://www.wikidata.org/prop/direct/P3219'), ('bname', 'Encyclopædia Universalis ID')]
# [('bar', 'http://www.wikidata.org/prop/direct/P3241'), ('bname', 'Catholic Encyclopedia ID')]
# [('bar', 'http://www.wikidata.org/prop/direct/P3365'), ('bname', 'Treccani ID')]
# [('bar', 'http://www.wikidata.org/prop/direct/P3417'), ('bname', 'Quora topic ID')]
# [('bar', 'http://www.wikidata.org/prop/direct/P3569'), ('bname', 'Cultureel Woordenboek ID')]
# [('bar', 'http://www.wikidata.org/prop/direct/P373'), ('bname', 'Commons category')]
# [('bar', 'http://www.wikidata.org/prop/direct/P3827'), ('bname', 'JSTOR topic ID')]
# [('bar', 'http://www.wikidata.org/prop/direct/P5019'), ('bname', 'Brockhaus Enzyklopädie online ID')]
# [('bar', 'http://www.wikidata.org/prop/direct/P5063'), ('bname', 'Interlingual Index ID')]
# [('bar', 'http://www.wikidata.org/prop/direct/P508'), ('bname', 'BNCF Thesaurus ID')]
# [('bar', 'http://www.wikidata.org/prop/direct/P527'), ('bname', 'has part')]
# [('bar', 'http://www.wikidata.org/prop/direct/P5604'), ('bname', 'archINFORM keyword ID')]
# [('bar', 'http://www.wikidata.org/prop/direct/P580'), ('bname', 'start time')]
# [('bar', 'http://www.wikidata.org/prop/direct/P582'), ('bname', 'end time')]
# [('bar', 'http://www.wikidata.org/prop/direct/P6058'), ('bname', 'Larousse ID')]
# [('bar', 'http://www.wikidata.org/prop/direct/P6366'), ('bname', 'Microsoft Academic ID')]
# [('bar', 'http://www.wikidata.org/prop/direct/P6404'), ('bname', "Treccani's Dizionario di Storia ID")]
# [('bar', 'http://www.wikidata.org/prop/direct/P6412'), ('bname', 'Gran Enciclopèdia de la Música ID')]
# [('bar', 'http://www.wikidata.org/prop/direct/P646'), ('bname', 'Freebase ID')]
# [('bar', 'http://www.wikidata.org/prop/direct/P6573'), ('bname', 'Klexikon article ID')]
# [('bar', 'http://www.wikidata.org/prop/direct/P737'), ('bname', 'influenced by')]
# [('bar', 'http://www.wikidata.org/prop/direct/P7786'), ('bname', 'Joconde epoch ID')]
# [('bar', 'http://www.wikidata.org/prop/direct/P7818'), ('bname', 'French Vikidia ID')]
# [('bar', 'http://www.wikidata.org/prop/direct/P7827'), ('bname', 'Spanish Vikidia ID')]
# [('bar', 'http://www.wikidata.org/prop/direct/P7982'), ('bname', 'Hrvatska enciklopedija ID')]
# [('bar', 'http://www.wikidata.org/prop/direct/P8135'), ('bname', 'Encyclopedia of České Budějovice ID')]
# [('bar', 'http://www.wikidata.org/prop/direct/P8349'), ('bname', 'Proleksis enciklopedija ID')]
# [('bar', 'http://www.wikidata.org/prop/direct/P8406'), ('bname', 'Grove Art Online ID')]
# [('bar', 'http://www.wikidata.org/prop/direct/P8432'), ('bname', 'Österreichisches Musiklexikon Online ID')]
# [('bar', 'http://www.wikidata.org/prop/direct/P8519'), ('bname', 'RKD thesaurus ID')]
# [('bar', 'http://www.wikidata.org/prop/direct/P8814'), ('bname', 'WordNet 3.1 Synset ID')]
# [('bar', 'http://www.wikidata.org/prop/direct/P902'), ('bname', 'HDS ID')]
# [('bar', 'http://www.wikidata.org/prop/direct/P910'), ('bname', "topic's main category")]
# [('bar', 'http://www.wikidata.org/prop/direct/P920'), ('bname', 'LEM ID')]
# [('bar', 'http://www.wikidata.org/prop/direct/P950'), ('bname', 'Biblioteca Nacional de España ID')]
# [('bar', 'http://www.wikidata.org/prop/direct/P989'), ('bname', 'spoken text audio')]
# [('bar', 'http://www.wikidata.org/prop/direct/P9779'), ('bname', 'abART term ID')]
# [('rena', 'http://www.wikidata.org/prop/direct/P1014'), ('ename', 'Art & Architecture Thesaurus ID')]
# [('rena', 'http://www.wikidata.org/prop/direct/P1051'), ('ename', 'PSH ID')]
# [('rena', 'http://www.wikidata.org/prop/direct/P1151'), ('ename', "topic's main Wikimedia portal")]
# [('rena', 'http://www.wikidata.org/prop/direct/P1256'), ('ename', 'Iconclass notation')]
# [('rena', 'http://www.wikidata.org/prop/direct/P1343'), ('ename', 'described by source')]
# [('rena', 'http://www.wikidata.org/prop/direct/P1417'), ('ename', 'Encyclopædia Britannica Online ID')]
# [('rena', 'http://www.wikidata.org/prop/direct/P1424'), ('ename', "topic's main template")]
# [('rena', 'http://www.wikidata.org/prop/direct/P155'), ('ename', 'follows')]
# [('rena', 'http://www.wikidata.org/prop/direct/P156'), ('ename', 'followed by')]
# [('rena', 'http://www.wikidata.org/prop/direct/P18'), ('ename', 'image')]
# [('rena', 'http://www.wikidata.org/prop/direct/P1807'), ('ename', 'Great Aragonese Encyclopedia ID')]
# [('rena', 'http://www.wikidata.org/prop/direct/P1889'), ('ename', 'different from')]
# [('rena', 'http://www.wikidata.org/prop/direct/P227'), ('ename', 'GND ID')]
# [('rena', 'http://www.wikidata.org/prop/direct/P2347'), ('ename', 'YSO ID')]
# [('rena', 'http://www.wikidata.org/prop/direct/P244'), ('ename', 'Library of Congress authority ID')]
# [('rena', 'http://www.wikidata.org/prop/direct/P2579'), ('ename', 'studied by')]
# [('rena', 'http://www.wikidata.org/prop/direct/P268'), ('ename', 'Bibliothèque nationale de France ID')]
# [('rena', 'http://www.wikidata.org/prop/direct/P276'), ('ename', 'location')]
# [('rena', 'http://www.wikidata.org/prop/direct/P2924'), ('ename', 'Great Russian Encyclopedia Online ID')]
# [('rena', 'http://www.wikidata.org/prop/direct/P31'), ('ename', 'instance of')]
# [('rena', 'http://www.wikidata.org/prop/direct/P3222'), ('ename', 'NE.se ID')]
# [('rena', 'http://www.wikidata.org/prop/direct/P3241'), ('ename', 'Catholic Encyclopedia ID')]
# [('rena', 'http://www.wikidata.org/prop/direct/P3417'), ('ename', 'Quora topic ID')]
# [('rena', 'http://www.wikidata.org/prop/direct/P349'), ('ename', 'National Diet Library ID')]
# [('rena', 'http://www.wikidata.org/prop/direct/P3553'), ('ename', 'Zhihu topic ID')]
# [('rena', 'http://www.wikidata.org/prop/direct/P373'), ('ename', 'Commons category')]
# [('rena', 'http://www.wikidata.org/prop/direct/P3827'), ('ename', 'JSTOR topic ID')]
# [('rena', 'http://www.wikidata.org/prop/direct/P4212'), ('ename', 'PACTOLS thesaurus ID')]
# [('rena', 'http://www.wikidata.org/prop/direct/P4342'), ('ename', 'Store norske leksikon ID')]
# [('rena', 'http://www.wikidata.org/prop/direct/P5008'), ('ename', 'on focus list of Wikimedia project')]
# [('rena', 'http://www.wikidata.org/prop/direct/P5063'), ('ename', 'Interlingual Index ID')]
# [('rena', 'http://www.wikidata.org/prop/direct/P508'), ('ename', 'BNCF Thesaurus ID')]
# [('rena', 'http://www.wikidata.org/prop/direct/P5125'), ('ename', 'Wikimedia outline')]
# [('rena', 'http://www.wikidata.org/prop/direct/P527'), ('ename', 'has part')]
# [('rena', 'http://www.wikidata.org/prop/direct/P580'), ('ename', 'start time')]
# [('rena', 'http://www.wikidata.org/prop/direct/P582'), ('ename', 'end time')]
# [('rena', 'http://www.wikidata.org/prop/direct/P6058'), ('ename', 'Larousse ID')]
# [('rena', 'http://www.wikidata.org/prop/direct/P6366'), ('ename', 'Microsoft Academic ID')]
# [('rena', 'http://www.wikidata.org/prop/direct/P6404'), ('ename', "Treccani's Dizionario di Storia ID")]
# [('rena', 'http://www.wikidata.org/prop/direct/P6412'), ('ename', 'Gran Enciclopèdia de la Música ID')]
# [('rena', 'http://www.wikidata.org/prop/direct/P646'), ('ename', 'Freebase ID')]
# [('rena', 'http://www.wikidata.org/prop/direct/P6573'), ('ename', 'Klexikon article ID')]
# [('rena', 'http://www.wikidata.org/prop/direct/P7033'), ('ename', 'Australian Educational Vocabulary ID')]
# [('rena', 'http://www.wikidata.org/prop/direct/P7786'), ('ename', 'Joconde epoch ID')]
# [('rena', 'http://www.wikidata.org/prop/direct/P7818'), ('ename', 'French Vikidia ID')]
# [('rena', 'http://www.wikidata.org/prop/direct/P7827'), ('ename', 'Spanish Vikidia ID')]
# [('rena', 'http://www.wikidata.org/prop/direct/P7829'), ('ename', 'English Vikidia ID')]
# [('rena', 'http://www.wikidata.org/prop/direct/P7832'), ('ename', 'Basque Vikidia ID')]
# [('rena', 'http://www.wikidata.org/prop/direct/P7982'), ('ename', 'Hrvatska enciklopedija ID')]
# [('rena', 'http://www.wikidata.org/prop/direct/P7993'), ('ename', "Treccani's Dizionario di Filosofia ID")]
# [('rena', 'http://www.wikidata.org/prop/direct/P8349'), ('ename', 'Proleksis enciklopedija ID')]
# [('rena', 'http://www.wikidata.org/prop/direct/P8406'), ('ename', 'Grove Art Online ID')]
# [('rena', 'http://www.wikidata.org/prop/direct/P8408'), ('ename', 'KBpedia ID')]
# [('rena', 'http://www.wikidata.org/prop/direct/P8432'), ('ename', 'Österreichisches Musiklexikon Online ID')]
# [('rena', 'http://www.wikidata.org/prop/direct/P902'), ('ename', 'HDS ID')]
# [('rena', 'http://www.wikidata.org/prop/direct/P910'), ('ename', "topic's main category")]
# [('rena', 'http://www.wikidata.org/prop/direct/P935'), ('ename', 'Commons gallery')]
# [('rena', 'http://www.wikidata.org/prop/direct/P8603'), ('ename', 'Istrapedia ID')]
# [('rena', 'http://www.wikidata.org/prop/direct/P4305'), ('ename', 'FOIH styles and cultures ID')]
# 165

# %% [markdown]
# ## Task 3
# Identify the BGP for composer, painter, sculptor and poet

# %%
# write your queries
queryString = """
SELECT DISTINCT ?p ?name
WHERE {
   # bind something
   # ?obj wdt:P106 ?p .
   # get the label
   # ?p sc:name ?name.
   FILTER(REGEX(?name,"composer"^^xsd:string))
}
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/entity/Q21680663'), ('name', 'classical composer')]
# [('p', 'http://www.wikidata.org/entity/Q21680699'), ('name', 'operetta composer')]
# [('p', 'http://www.wikidata.org/entity/Q1415090'), ('name', 'film score composer')]
# [('p', 'http://www.wikidata.org/entity/Q36834'), ('name', 'composer')]
# [('p', 'http://www.wikidata.org/entity/Q2627699'), ('name', 'chess composer')]
# [('p', 'http://www.wikidata.org/entity/Q21680731'), ('name', 'opera composer')]
# [('p', 'http://www.wikidata.org/entity/Q63536580'), ('name', 'video game composer')]
# [('p', 'http://www.wikidata.org/entity/Q64356038'), ('name', 'musical theatre composer')]
# [('p', 'http://www.wikidata.org/entity/Q108001849'), ('name', 'amateur composer')]
# [('p', 'http://www.wikidata.org/entity/Q28771895'), ('name', 'vocal composer')]
# [('p', 'http://www.wikidata.org/entity/Q4765165'), ('name', 'Anime composer')]
# 11

# %%
#[('p', 'http://www.wikidata.org/entity/Q36834'), ('name', 'composer')]
queryString = """
SELECT DISTINCT ?p ?name
WHERE {
   # bind something
   # ?obj wdt:P106 ?p .
   # get the label
   # ?p sc:name ?name.
   FILTER(REGEX(?name,"sculptor"^^xsd:string))
}
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/entity/Q1281618'), ('name', 'sculptor')]
# [('p', 'http://www.wikidata.org/entity/Q10611691'), ('name', 'ornamental sculptor')]
# [('p', 'http://www.wikidata.org/entity/Q40749908'), ('name', 'bronze sculptor')]
# 3

# %%
#[('p', 'http://www.wikidata.org/entity/Q36834'), ('name', 'composer')]
#[('p', 'http://www.wikidata.org/entity/Q1281618'), ('name', 'sculptor')]
queryString = """
SELECT DISTINCT ?p ?name
WHERE {
   # bind something
   # ?obj wdt:P106 ?p .
   # get the label
   # ?p sc:name ?name.
   FILTER(REGEX(?name,"painter"^^xsd:string))
}
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/entity/Q17505911'), ('name', 'architectural painter')]
# [('p', 'http://www.wikidata.org/entity/Q11606844'), ('name', 'Buddhist painter')]
# [('p', 'http://www.wikidata.org/entity/Q67200599'), ('name', 'Yōga painter')]
# [('p', 'http://www.wikidata.org/entity/Q67649782'), ('name', 'finger painter')]
# [('p', 'http://www.wikidata.org/entity/Q1743189'), ('name', 'church-painter')]
# [('p', 'http://www.wikidata.org/entity/Q59938355'), ('name', 'flower painter')]
# [('p', 'http://www.wikidata.org/entity/Q25616553'), ('name', 'marine painter')]
# [('p', 'http://www.wikidata.org/entity/Q15301511'), ('name', 'vase painter')]
# [('p', 'http://www.wikidata.org/entity/Q15303031'), ('name', 'black-figure vase painter')]
# [('p', 'http://www.wikidata.org/entity/Q15303045'), ('name', 'red-figure vase painter')]
# [('p', 'http://www.wikidata.org/entity/Q21282419'), ('name', 'Attic vase-painter')]
# [('p', 'http://www.wikidata.org/entity/Q41000669'), ('name', 'white-groud vase-painter')]
# [('p', 'http://www.wikidata.org/entity/Q24692846'), ('name', 'Etruscan vase-painter')]
# [('p', 'http://www.wikidata.org/entity/Q22669155'), ('name', 'fresco painter')]
# [('p', 'http://www.wikidata.org/entity/Q30144139'), ('name', 'Corinthian vase-painter')]
# [('p', 'http://www.wikidata.org/entity/Q108256086'), ('name', 'faience painter')]
# [('p', 'http://www.wikidata.org/entity/Q59924426'), ('name', 'oil painter')]
# [('p', 'http://www.wikidata.org/entity/Q27469950'), ('name', 'laconian vase-painter')]
# [('p', 'http://www.wikidata.org/entity/Q1028181'), ('name', 'painter')]
# [('p', 'http://www.wikidata.org/entity/Q288728'), ('name', 'painter and varnisher')]
# 20

# %%
#[('p', 'http://www.wikidata.org/entity/Q36834'), ('name', 'composer')]
#[('p', 'http://www.wikidata.org/entity/Q1281618'), ('name', 'sculptor')]
#[('p', 'http://www.wikidata.org/entity/Q1028181'), ('name', 'painter')]

queryString = """
SELECT DISTINCT ?p ?name
WHERE {
   # bind something
   # ?obj wdt:P106 ?p .
   # get the label
   # ?p sc:name ?name.
   FILTER(REGEX(?name,"poet"^^xsd:string))
}
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/entity/Q106376813'), ('name', 'visual poet')]
# [('p', 'http://www.wikidata.org/entity/Q1209498'), ('name', 'poet lawyer')]
# [('p', 'http://www.wikidata.org/entity/Q482'), ('name', 'poetry')]
# [('p', 'http://www.wikidata.org/entity/Q49757'), ('name', 'poet')]
# [('p', 'http://www.wikidata.org/entity/Q182357'), ('name', 'lyric poetry')]
# [('p', 'http://www.wikidata.org/entity/Q11386386'), ('name', 'haiku poet')]
# [('p', 'http://www.wikidata.org/entity/Q11122954'), ('name', 'tanka poet')]
# [('p', 'http://www.wikidata.org/entity/Q23117687'), ('name', 'dithyrambic poet')]
# [('p', 'http://www.wikidata.org/entity/Q1237928'), ('name', 'poet laureate')]
# [('p', 'http://www.wikidata.org/entity/Q2293636'), ('name', 'slam poet')]
# [('p', 'http://www.wikidata.org/entity/Q7168247'), ('name', 'performance poetry')]
# [('p', 'http://www.wikidata.org/entity/Q7207537'), ('name', 'poetry reading')]
# [('p', 'http://www.wikidata.org/entity/Q107714046'), ('name', 'performance poet')]
# [('p', 'http://www.wikidata.org/entity/Q107230508'), ('name', 'woman poet')]
# [('p', 'http://www.wikidata.org/entity/Q17378131'), ('name', 'dub poet')]
# [('p', 'http://www.wikidata.org/entity/Q104824215'), ('name', 'poetry teacher')]
# [('p', 'http://www.wikidata.org/entity/Q12901590'), ('name', 'poetaster')]
# [('p', 'http://www.wikidata.org/entity/Q2293670'), ('name', 'slam poetry')]
# [('p', 'http://www.wikidata.org/entity/Q3401082'), ('name', 'war poet')]
# [('p', 'http://www.wikidata.org/entity/Q20528752'), ('name', 'concrete poet')]
# 20

# %%
#[('p', 'http://www.wikidata.org/entity/Q36834'), ('name', 'composer')]
#[('p', 'http://www.wikidata.org/entity/Q1281618'), ('name', 'sculptor')]
#[('p', 'http://www.wikidata.org/entity/Q1028181'), ('name', 'painter')]
#[('p', 'http://www.wikidata.org/entity/Q49757'), ('name', 'poet')]
queryString = """
SELECT DISTINCT ?com ?cname ?scul ?sname ?paint ?pname ?poet ?poname
WHERE {
   {
    wd:Q36843 ?obj ?com.
    # ?com sc:name ?cname.
    }
    UNION
    {
    wd:Q1281618 ?obj1 ?scul.
    # ?scul sc:name ?sname.
    }
    UNION 
    {
    wd:Q1028181 ?obj2 ?paint.
    # ?paint sc:name ?pname.
   }
   UNION 
    {
    wd:Q49757 ?obj3 ?poet.
    # ?poet sc:name ?poname.
   }
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('com', 'http://www.wikidata.org/entity/Q17856046'), ('cname', 'member of the Reichstag of Nazi Germany')]
# [('com', 'http://www.wikidata.org/entity/Q708038'), ('cname', 'Kaiser Wilhelm Society')]
# [('com', 'http://www.wikidata.org/entity/Q22082717'), ('cname', 'eugenicist')]
# [('com', 'http://www.wikidata.org/entity/Q10737'), ('cname', 'suicide')]
# [('com', 'http://www.wikidata.org/entity/Q152838'), ('cname', 'University of Göttingen')]
# [('com', 'http://www.wikidata.org/entity/Q183'), ('cname', 'Germany')]
# [('com', 'http://www.wikidata.org/entity/Q188'), ('cname', 'German')]
# [('com', 'http://www.wikidata.org/entity/Q210392'), ('cname', 'killed in action')]
# [('com', 'http://www.wikidata.org/entity/Q2865'), ('cname', 'Kassel')]
# [('com', 'http://www.wikidata.org/entity/Q39631'), ('cname', 'physician')]
# [('com', 'http://www.wikidata.org/entity/Q41304'), ('cname', 'Weimar Republic')]
# [('com', 'http://www.wikidata.org/entity/Q482980'), ('cname', 'author')]
# [('com', 'http://www.wikidata.org/entity/Q499249'), ('cname', 'Walter')]
# [('com', 'http://www.wikidata.org/entity/Q5'), ('cname', 'human')]
# [('com', 'http://www.wikidata.org/entity/Q55044'), ('cname', 'Ludwig Maximilian University of Munich')]
# [('com', 'http://www.wikidata.org/entity/Q64'), ('cname', 'Berlin')]
# [('com', 'http://www.wikidata.org/entity/Q6581097'), ('cname', 'male')]
# [('com', 'http://www.wikidata.org/entity/Q7318'), ('cname', 'Nazi Germany')]
# [('com', 'http://www.wikidata.org/entity/Q7320'), ('cname', "National Socialist German Workers' Party (Nazi Party)")]
# [('com', 'http://www.wikidata.org/entity/Q82955'), ('cname', 'politician')]
# [('com', 'http://www.wikidata.org/entity/Q153978'), ('cname', 'University of Tübingen')]
# [('com', 'http://www.wikidata.org/entity/Q2628227'), ('cname', 'Doctor of Sciences')]
# [('com', 'http://www.wikidata.org/entity/Q16755977'), ('cname', 'racial theorist')]
# [('com', 'http://www.wikidata.org/entity/Q1969310'), ('cname', 'Nationalsozialistischer Deutscher Ärzte-Bund')]
# [('com', 'http://www.wikidata.org/entity/Q14290163'), ('cname', 'Gross')]
# [('com', 'http://www.wikidata.org/entity/Q15954665'), ('cname', 'antisemite')]
# [('com', 'http://www.wikidata.org/entity/Q574173'), ('cname', 'NSDAP Office of Racial Policy')]
# [('scul', 'http://www.wikidata.org/entity/Q98552221'), ('sname', 'plastic artist')]
# [('scul', 'http://www.wikidata.org/entity/Q5914426'), ('sname', 'Template:Infobox artist')]
# [('scul', 'http://www.wikidata.org/entity/Q12737077'), ('sname', 'occupation')]
# [('scul', 'http://www.wikidata.org/entity/Q28640'), ('sname', 'profession')]
# [('scul', 'http://www.wikidata.org/entity/Q30059240'), ('sname', "Real'nyj slovar' klassicheskih drevnostej po Ljubkeru")]
# [('scul', 'http://www.wikidata.org/entity/Q860861'), ('sname', 'sculpture')]
# [('scul', 'http://www.wikidata.org/entity/Q11634'), ('sname', 'art of sculpture')]
# [('scul', 'http://www.wikidata.org/entity/Q3391743'), ('sname', 'visual artist')]
# [('scul', 'http://www.wikidata.org/entity/Q7022076'), ('sname', 'Category:Sculptors')]
# [('scul', 'http://www.wikidata.org/entity/Q8907444'), ('sname', 'Category:Wikipedia categories named after sculptors')]
# [('scul', 'http://www.wikidata.org/entity/Q1458549'), ('sname', 'list of sculptors')]
# [('paint', 'http://www.wikidata.org/entity/Q1027879'), ('pname', 'graphics')]
# [('paint', 'http://www.wikidata.org/entity/Q128538'), ('pname', 'Luke the Evangelist')]
# [('paint', 'http://www.wikidata.org/entity/Q5914426'), ('pname', 'Template:Infobox artist')]
# [('paint', 'http://www.wikidata.org/entity/Q6615720'), ('pname', 'Category:Painters')]
# [('paint', 'http://www.wikidata.org/entity/Q11629'), ('pname', 'art of painting')]
# [('paint', 'http://www.wikidata.org/entity/Q12737077'), ('pname', 'occupation')]
# [('paint', 'http://www.wikidata.org/entity/Q174705'), ('pname', 'oil painting')]
# [('paint', 'http://www.wikidata.org/entity/Q28640'), ('pname', 'profession')]
# [('paint', 'http://www.wikidata.org/entity/Q174219'), ('pname', 'paint')]
# [('paint', 'http://www.wikidata.org/entity/Q189085'), ('pname', 'pastel')]
# [('paint', 'http://www.wikidata.org/entity/Q3391743'), ('pname', 'visual artist')]
# [('paint', 'http://www.wikidata.org/entity/Q193897'), ('pname', 'paintbrush')]
# [('paint', 'http://www.wikidata.org/entity/Q3300034'), ('pname', 'painting material')]
# [('paint', 'http://www.wikidata.org/entity/Q861259'), ('pname', 'painting surface')]
# [('paint', 'http://www.wikidata.org/entity/Q425548'), ('pname', 'palette')]
# [('paint', 'http://www.wikidata.org/entity/Q939611'), ('pname', 'easel')]
# [('paint', 'http://www.wikidata.org/entity/P4687'), ('pname', 'Dictionnaire des peintres belges ID')]
# [('paint', 'http://www.wikidata.org/entity/Q1375139'), ('pname', 'Malíř')]
# [('paint', 'http://www.wikidata.org/entity/Q8538537'), ('pname', 'Category:Wikipedia categories named after painters')]
# [('poet', 'http://www.wikidata.org/entity/Q106727050'), ('poname', 'Metropolitan Museum of Art Tagging Vocabulary')]
# [('poet', 'http://www.wikidata.org/entity/Q28640'), ('poname', 'profession')]
# [('poet', 'http://www.wikidata.org/entity/Q36180'), ('poname', 'writer')]
# [('poet', 'http://www.wikidata.org/entity/Q482'), ('poname', 'poetry')]
# [('poet', 'http://www.wikidata.org/entity/Q1293108'), ('poname', 'Dichter')]
# [('poet', 'http://www.wikidata.org/entity/Q6487149'), ('poname', 'Category:Poets')]
# [('poet', 'http://www.wikidata.org/entity/P5509'), ('poname', 'MAPS poet ID')]
# [('poet', 'http://www.wikidata.org/entity/P5477'), ('poname', 'Les Voix de la poésie poet ID')]
# [('poet', 'http://www.wikidata.org/entity/P5506'), ('poname', 'Poetry In Voice poet ID')]
# [('poet', 'http://www.wikidata.org/entity/P5710'), ('poname', 'Recours au poème ID')]
# [('poet', 'http://www.wikidata.org/entity/P5430'), ('poname', 'Poetry International Web poet ID')]
# [('poet', 'http://www.wikidata.org/entity/P5343'), ('poname', 'Poets.org poet ID')]
# [('poet', 'http://www.wikidata.org/entity/P5609'), ('poname', 'Split This Rock poet ID')]
# [('poet', 'http://www.wikidata.org/entity/Q9579555'), ('poname', 'Category:Wikipedia categories named after poets')]
# [('poet', 'http://www.wikidata.org/entity/P5503'), ('poname', 'Poetry Society of America poet ID')]
# [('poet', 'http://www.wikidata.org/entity/P5344'), ('poname', 'Printemps des poètes poet ID')]
# [('poet', 'http://www.wikidata.org/entity/P5393'), ('poname', 'cipM poet ID')]
# [('poet', 'http://www.wikidata.org/entity/P5394'), ('poname', 'Poets & Writers author ID')]
# [('poet', 'http://www.wikidata.org/entity/P5465'), ('poname', 'Australian Poetry Library poet ID')]
# [('poet', 'http://www.wikidata.org/entity/P5341'), ('poname', 'Poetry Foundation ID')]
# [('poet', 'http://www.wikidata.org/entity/P5392'), ('poname', 'Poetry Archive poet ID')]
# [('poet', 'http://www.wikidata.org/entity/P5470'), ('poname', 'Scottish Poetry Library poet ID')]
# [('poet', 'http://www.wikidata.org/entity/P5478'), ('poname', 'RPO poet ID')]
# 80

# %% [markdown]
# Final query for this task

# %%
# write your final query
#[('p', 'http://www.wikidata.org/entity/Q36834'), ('name', 'composer')]
#[('p', 'http://www.wikidata.org/entity/Q1281618'), ('name', 'sculptor')]
#[('p', 'http://www.wikidata.org/entity/Q1028181'), ('name', 'painter')]
#[('p', 'http://www.wikidata.org/entity/Q49757'), ('name', 'poet')]
queryString = """
SELECT DISTINCT ?com ?cname ?scul ?sname ?paint ?pname ?poet ?poname
WHERE {
   {
    wd:Q36843 ?com ?obj.
    # ?com sc:name ?cname.
    }
    UNION
    {
    wd:Q1281618 ?obj1 ?scul.
    # ?scul sc:name ?sname.
    }
    UNION 
    {
    wd:Q1028181 ?obj2 ?paint.
    # ?paint sc:name ?pname.
   }
   UNION 
    {
    wd:Q49757 ?obj3 ?poet.
    # ?poet sc:name ?poname.
   }
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('com', 'http://www.wikidata.org/prop/direct/P9044'), ('cname', 'GEPRIS-Historisch ID (Person)')]
# [('com', 'http://www.wikidata.org/prop/direct/P1006'), ('cname', 'Nationale Thesaurus voor Auteurs ID')]
# [('com', 'http://www.wikidata.org/prop/direct/P1015'), ('cname', 'NORAF ID')]
# [('com', 'http://www.wikidata.org/prop/direct/P102'), ('cname', 'member of political party')]
# [('com', 'http://www.wikidata.org/prop/direct/P106'), ('cname', 'occupation')]
# [('com', 'http://www.wikidata.org/prop/direct/P119'), ('cname', 'place of burial')]
# [('com', 'http://www.wikidata.org/prop/direct/P1196'), ('cname', 'manner of death')]
# [('com', 'http://www.wikidata.org/prop/direct/P1207'), ('cname', 'NUKAT ID')]
# [('com', 'http://www.wikidata.org/prop/direct/P1280'), ('cname', 'CONOR.SI ID')]
# [('com', 'http://www.wikidata.org/prop/direct/P1347'), ('cname', 'military casualty classification')]
# [('com', 'http://www.wikidata.org/prop/direct/P1412'), ('cname', 'languages spoken, written or signed')]
# [('com', 'http://www.wikidata.org/prop/direct/P18'), ('cname', 'image')]
# [('com', 'http://www.wikidata.org/prop/direct/P19'), ('cname', 'place of birth')]
# [('com', 'http://www.wikidata.org/prop/direct/P20'), ('cname', 'place of death')]
# [('com', 'http://www.wikidata.org/prop/direct/P21'), ('cname', 'sex or gender')]
# [('com', 'http://www.wikidata.org/prop/direct/P213'), ('cname', 'ISNI')]
# [('com', 'http://www.wikidata.org/prop/direct/P214'), ('cname', 'VIAF ID')]
# [('com', 'http://www.wikidata.org/prop/direct/P227'), ('cname', 'GND ID')]
# [('com', 'http://www.wikidata.org/prop/direct/P244'), ('cname', 'Library of Congress authority ID')]
# [('com', 'http://www.wikidata.org/prop/direct/P269'), ('cname', 'IdRef ID')]
# [('com', 'http://www.wikidata.org/prop/direct/P27'), ('cname', 'country of citizenship')]
# [('com', 'http://www.wikidata.org/prop/direct/P2949'), ('cname', 'WikiTree person ID')]
# [('com', 'http://www.wikidata.org/prop/direct/P31'), ('cname', 'instance of')]
# [('com', 'http://www.wikidata.org/prop/direct/P373'), ('cname', 'Commons category')]
# [('com', 'http://www.wikidata.org/prop/direct/P39'), ('cname', 'position held')]
# [('com', 'http://www.wikidata.org/prop/direct/P4293'), ('cname', 'PM20 folder ID')]
# [('com', 'http://www.wikidata.org/prop/direct/P463'), ('cname', 'member of')]
# [('com', 'http://www.wikidata.org/prop/direct/P512'), ('cname', 'academic degree')]
# [('com', 'http://www.wikidata.org/prop/direct/P569'), ('cname', 'date of birth')]
# [('com', 'http://www.wikidata.org/prop/direct/P570'), ('cname', 'date of death')]
# [('com', 'http://www.wikidata.org/prop/direct/P646'), ('cname', 'Freebase ID')]
# [('com', 'http://www.wikidata.org/prop/direct/P69'), ('cname', 'educated at')]
# [('com', 'http://www.wikidata.org/prop/direct/P734'), ('cname', 'family name')]
# [('com', 'http://www.wikidata.org/prop/direct/P735'), ('cname', 'given name')]
# [('com', 'http://www.wikidata.org/prop/direct/P7859'), ('cname', 'WorldCat Identities ID')]
# [('com', 'http://www.wikidata.org/prop/direct/P7902'), ('cname', 'Deutsche Biographie (GND) ID')]
# [('com', 'http://www.wikidata.org/prop/direct/P800'), ('cname', 'notable work')]
# [('com', 'http://www.wikidata.org/prop/direct/P949'), ('cname', 'National Library of Israel ID')]
# [('scul', 'http://www.wikidata.org/entity/Q98552221'), ('sname', 'plastic artist')]
# [('scul', 'http://www.wikidata.org/entity/Q5914426'), ('sname', 'Template:Infobox artist')]
# [('scul', 'http://www.wikidata.org/entity/Q12737077'), ('sname', 'occupation')]
# [('scul', 'http://www.wikidata.org/entity/Q28640'), ('sname', 'profession')]
# [('scul', 'http://www.wikidata.org/entity/Q30059240'), ('sname', "Real'nyj slovar' klassicheskih drevnostej po Ljubkeru")]
# [('scul', 'http://www.wikidata.org/entity/Q860861'), ('sname', 'sculpture')]
# [('scul', 'http://www.wikidata.org/entity/Q11634'), ('sname', 'art of sculpture')]
# [('scul', 'http://www.wikidata.org/entity/Q3391743'), ('sname', 'visual artist')]
# [('scul', 'http://www.wikidata.org/entity/Q7022076'), ('sname', 'Category:Sculptors')]
# [('scul', 'http://www.wikidata.org/entity/Q8907444'), ('sname', 'Category:Wikipedia categories named after sculptors')]
# [('scul', 'http://www.wikidata.org/entity/Q1458549'), ('sname', 'list of sculptors')]
# [('paint', 'http://www.wikidata.org/entity/Q1027879'), ('pname', 'graphics')]
# [('paint', 'http://www.wikidata.org/entity/Q128538'), ('pname', 'Luke the Evangelist')]
# [('paint', 'http://www.wikidata.org/entity/Q5914426'), ('pname', 'Template:Infobox artist')]
# [('paint', 'http://www.wikidata.org/entity/Q6615720'), ('pname', 'Category:Painters')]
# [('paint', 'http://www.wikidata.org/entity/Q11629'), ('pname', 'art of painting')]
# [('paint', 'http://www.wikidata.org/entity/Q12737077'), ('pname', 'occupation')]
# [('paint', 'http://www.wikidata.org/entity/Q174705'), ('pname', 'oil painting')]
# [('paint', 'http://www.wikidata.org/entity/Q28640'), ('pname', 'profession')]
# [('paint', 'http://www.wikidata.org/entity/Q174219'), ('pname', 'paint')]
# [('paint', 'http://www.wikidata.org/entity/Q189085'), ('pname', 'pastel')]
# [('paint', 'http://www.wikidata.org/entity/Q3391743'), ('pname', 'visual artist')]
# [('paint', 'http://www.wikidata.org/entity/Q193897'), ('pname', 'paintbrush')]
# [('paint', 'http://www.wikidata.org/entity/Q3300034'), ('pname', 'painting material')]
# [('paint', 'http://www.wikidata.org/entity/Q861259'), ('pname', 'painting surface')]
# [('paint', 'http://www.wikidata.org/entity/Q425548'), ('pname', 'palette')]
# [('paint', 'http://www.wikidata.org/entity/Q939611'), ('pname', 'easel')]
# [('paint', 'http://www.wikidata.org/entity/P4687'), ('pname', 'Dictionnaire des peintres belges ID')]
# [('paint', 'http://www.wikidata.org/entity/Q1375139'), ('pname', 'Malíř')]
# [('paint', 'http://www.wikidata.org/entity/Q8538537'), ('pname', 'Category:Wikipedia categories named after painters')]
# [('poet', 'http://www.wikidata.org/entity/Q106727050'), ('poname', 'Metropolitan Museum of Art Tagging Vocabulary')]
# [('poet', 'http://www.wikidata.org/entity/Q28640'), ('poname', 'profession')]
# [('poet', 'http://www.wikidata.org/entity/Q36180'), ('poname', 'writer')]
# [('poet', 'http://www.wikidata.org/entity/Q482'), ('poname', 'poetry')]
# [('poet', 'http://www.wikidata.org/entity/Q1293108'), ('poname', 'Dichter')]
# [('poet', 'http://www.wikidata.org/entity/Q6487149'), ('poname', 'Category:Poets')]
# [('poet', 'http://www.wikidata.org/entity/P5509'), ('poname', 'MAPS poet ID')]
# [('poet', 'http://www.wikidata.org/entity/P5477'), ('poname', 'Les Voix de la poésie poet ID')]
# [('poet', 'http://www.wikidata.org/entity/P5506'), ('poname', 'Poetry In Voice poet ID')]
# [('poet', 'http://www.wikidata.org/entity/P5710'), ('poname', 'Recours au poème ID')]
# [('poet', 'http://www.wikidata.org/entity/P5430'), ('poname', 'Poetry International Web poet ID')]
# [('poet', 'http://www.wikidata.org/entity/P5343'), ('poname', 'Poets.org poet ID')]
# [('poet', 'http://www.wikidata.org/entity/P5609'), ('poname', 'Split This Rock poet ID')]
# [('poet', 'http://www.wikidata.org/entity/Q9579555'), ('poname', 'Category:Wikipedia categories named after poets')]
# [('poet', 'http://www.wikidata.org/entity/P5503'), ('poname', 'Poetry Society of America poet ID')]
# [('poet', 'http://www.wikidata.org/entity/P5344'), ('poname', 'Printemps des poètes poet ID')]
# [('poet', 'http://www.wikidata.org/entity/P5393'), ('poname', 'cipM poet ID')]
# [('poet', 'http://www.wikidata.org/entity/P5394'), ('poname', 'Poets & Writers author ID')]
# [('poet', 'http://www.wikidata.org/entity/P5465'), ('poname', 'Australian Poetry Library poet ID')]
# [('poet', 'http://www.wikidata.org/entity/P5341'), ('poname', 'Poetry Foundation ID')]
# [('poet', 'http://www.wikidata.org/entity/P5392'), ('poname', 'Poetry Archive poet ID')]
# [('poet', 'http://www.wikidata.org/entity/P5470'), ('poname', 'Scottish Poetry Library poet ID')]
# [('poet', 'http://www.wikidata.org/entity/P5478'), ('poname', 'RPO poet ID')]
# 91

# %% [markdown]
# ## Task 4
# Consider Renaissance, Baroque and Romanticism. Find how many composers, painters, sculptors and poets belong to those cultural movements (the results set must be a list of triples movement, job, #people)

# %%
# Considering Occupation ID for getting all professions 
#
queryString = """
SELECT DISTINCT ?roman ?rname 
WHERE {
    # ?r wdt:P106 ?roman.
    # ?roman sc:name ?rname.
    FILTER(REGEX(?rname, "poet"^^xsd:string))
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('roman', 'http://www.wikidata.org/entity/Q106376813'), ('rname', 'visual poet')]
# [('roman', 'http://www.wikidata.org/entity/Q1209498'), ('rname', 'poet lawyer')]
# [('roman', 'http://www.wikidata.org/entity/Q482'), ('rname', 'poetry')]
# [('roman', 'http://www.wikidata.org/entity/Q49757'), ('rname', 'poet')]
# [('roman', 'http://www.wikidata.org/entity/Q182357'), ('rname', 'lyric poetry')]
# [('roman', 'http://www.wikidata.org/entity/Q11386386'), ('rname', 'haiku poet')]
# [('roman', 'http://www.wikidata.org/entity/Q11122954'), ('rname', 'tanka poet')]
# [('roman', 'http://www.wikidata.org/entity/Q23117687'), ('rname', 'dithyrambic poet')]
# [('roman', 'http://www.wikidata.org/entity/Q1237928'), ('rname', 'poet laureate')]
# [('roman', 'http://www.wikidata.org/entity/Q2293636'), ('rname', 'slam poet')]
# [('roman', 'http://www.wikidata.org/entity/Q7168247'), ('rname', 'performance poetry')]
# [('roman', 'http://www.wikidata.org/entity/Q7207537'), ('rname', 'poetry reading')]
# [('roman', 'http://www.wikidata.org/entity/Q107714046'), ('rname', 'performance poet')]
# [('roman', 'http://www.wikidata.org/entity/Q107230508'), ('rname', 'woman poet')]
# [('roman', 'http://www.wikidata.org/entity/Q17378131'), ('rname', 'dub poet')]
# [('roman', 'http://www.wikidata.org/entity/Q104824215'), ('rname', 'poetry teacher')]
# [('roman', 'http://www.wikidata.org/entity/Q12901590'), ('rname', 'poetaster')]
# [('roman', 'http://www.wikidata.org/entity/Q2293670'), ('rname', 'slam poetry')]
# [('roman', 'http://www.wikidata.org/entity/Q3401082'), ('rname', 'war poet')]
# [('roman', 'http://www.wikidata.org/entity/Q20528752'), ('rname', 'concrete poet')]
# [('roman', 'http://www.wikidata.org/entity/Q73644030'), ('rname', 'urdu poets')]
# [('roman', 'http://www.wikidata.org/entity/Q104236711'), ('rname', 'modern poetry scholar')]
# 22

# %%
# write your queries
#[('p', 'http://www.wikidata.org/entity/Q37068'), ('name', 'Romanticism')]
#[('p', 'http://www.wikidata.org/entity/Q37853'), ('name', 'Baroque')]
#[('p', 'http://www.wikidata.org/entity/Q4692'), ('name', 'Renaissance')]
#[('NumOf', '156'), ('ocup', 'http://www.wikidata.org/entity/Q1028181'), ('oname', 'painter')]
#[('p', 'http://www.wikidata.org/entity/Q36834'), ('name', 'composer')]
#[('p', 'http://www.wikidata.org/entity/Q1281618'), ('name', 'sculptor')]
#[('p', 'http://www.wikidata.org/entity/Q1028181'), ('name', 'painter')]
#[('p', 'http://www.wikidata.org/entity/Q49757'), ('name', 'poet')]
queryString = """
SELECT  *
WHERE {
    {SELECT DISTINCT (COUNT(?roman) as ?Num) ?ocup (?oname as ?Romanticism)  WHERE
    {
    # ?roman ?obj wd:Q37068;
        wdt:P106 ?ocup.
    # ?roman sc:name ?rname.
    # ?ocup sc:name ?oname.
    FILTER (REGEX(?oname, "sculptor"^^xsd:string) || REGEX(?oname, "composer"^^xsd:string ) || REGEX(?oname, "poet"^^xsd:string ) || REGEX(?oname, "painter"^^xsd:string ))
    #FILTER (REGEX(?oname, "painter"^^xsd:string ))
    #FILTER (?oname = 'sculptor'^^xsd:string || ?oname = 'painter'^^xsd:string) 
    } GROUP BY ?oname ?ocup
    }
    UNION
    {
    select distinct (COUNT(?bar) as ?Num) ?ocup1 (?oname1 as ?Boroque) where
    {
     # ?bar ?obj1 wd:Q37853;
         wdt:P106 ?ocup1.
    #?bar sc:name ?bname.
    # ?ocup1 sc:name ?oname1.
    FILTER (REGEX(?oname1, "sculptor"^^xsd:string ) || REGEX(?oname1, "painter"^^xsd:string ) || REGEX(?oname1, "poet"^^xsd:string)  || REGEX(?oname1, "composer"^^xsd:string ))
    } GROUP BY ?oname1 ?ocup1
    }
    UNION
    {
    select distinct (COUNT(?rena) as ?Num) ?ocup2 ?oname2 as ?Renaissance
    {
     # ?rena ?obj2 wd:Q4692;
         wdt:P106 ?ocup2.
    # ?rena sc:name ?ename.
    # ?ocup2 sc:name ?oname2.
    FILTER (REGEX(?oname2, "sculptor"^^xsd:string ) || REGEX(?oname2, "painter"^^xsd:string ) || REGEX(?oname2, "poet"^^xsd:string)  || REGEX(?oname2, "composer"^^xsd:string ))
    #FILTER (?oname2 = "sculptor"^^xsd:string || ?oname2 = "painter"^^xsd:string) 
   } 
   GROUP BY ?oname2 ?ocup2
   }
   
}  
LIMIT 500
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('Num', '8'), ('ocup', 'http://www.wikidata.org/entity/Q1209498'), ('Romanticism', 'poet lawyer')]
# [('Num', '1'), ('ocup', 'http://www.wikidata.org/entity/Q59938438'), ('Romanticism', 'history painter')]
# [('Num', '7'), ('ocup', 'http://www.wikidata.org/entity/Q21600439'), ('Romanticism', 'landscape painter')]
# [('Num', '21'), ('ocup', 'http://www.wikidata.org/entity/Q36834'), ('Romanticism', 'composer')]
# [('Num', '156'), ('ocup', 'http://www.wikidata.org/entity/Q1028181'), ('Romanticism', 'painter')]
# [('Num', '1'), ('ocup', 'http://www.wikidata.org/entity/Q21680663'), ('Romanticism', 'classical composer')]
# [('Num', '1'), ('ocup', 'http://www.wikidata.org/entity/Q2627699'), ('Romanticism', 'chess composer')]
# [('Num', '159'), ('ocup', 'http://www.wikidata.org/entity/Q49757'), ('Romanticism', 'poet')]
# [('Num', '14'), ('ocup', 'http://www.wikidata.org/entity/Q1281618'), ('Romanticism', 'sculptor')]
# [('Num', '1'), ('ocup1', 'http://www.wikidata.org/entity/Q28947943'), ('Boroque', 'miniature painter')]
# [('Num', '1'), ('ocup1', 'http://www.wikidata.org/entity/Q21600439'), ('Boroque', 'landscape painter')]
# [('Num', '12'), ('ocup1', 'http://www.wikidata.org/entity/Q36834'), ('Boroque', 'composer')]
# [('Num', '388'), ('ocup1', 'http://www.wikidata.org/entity/Q1028181'), ('Boroque', 'painter')]
# [('Num', '3'), ('ocup1', 'http://www.wikidata.org/entity/Q22669155'), ('Boroque', 'fresco painter')]
# [('Num', '1'), ('ocup1', 'http://www.wikidata.org/entity/Q21680663'), ('Boroque', 'classical composer')]
# [('Num', '2'), ('ocup1', 'http://www.wikidata.org/entity/Q1183704'), ('Boroque', 'decorative painter')]
# [('Num', '330'), ('ocup1', 'http://www.wikidata.org/entity/Q1281618'), ('Boroque', 'sculptor')]
# [('Num', '1'), ('ocup1', 'http://www.wikidata.org/entity/Q24056480'), ('Boroque', 'porcelain painter')]
# [('Num', '43'), ('ocup1', 'http://www.wikidata.org/entity/Q49757'), ('Boroque', 'poet')]
# [('Num', '1'), ('ocup1', 'http://www.wikidata.org/entity/Q984276'), ('Boroque', 'court painter')]
# [('Num', '1'), ('ocup1', 'http://www.wikidata.org/entity/Q288728'), ('Boroque', 'painter and varnisher')]
# [('Num', '1'), ('ocup2', 'http://www.wikidata.org/entity/Q1209498'), ('Renaissance', 'poet lawyer')]
# [('Num', '12'), ('ocup2', 'http://www.wikidata.org/entity/Q36834'), ('Renaissance', 'composer')]
# [('Num', '67'), ('ocup2', 'http://www.wikidata.org/entity/Q1028181'), ('Renaissance', 'painter')]
# [('Num', '3'), ('ocup2', 'http://www.wikidata.org/entity/Q22669155'), ('Renaissance', 'fresco painter')]
# [('Num', '26'), ('ocup2', 'http://www.wikidata.org/entity/Q1281618'), ('Renaissance', 'sculptor')]
# [('Num', '16'), ('ocup2', 'http://www.wikidata.org/entity/Q49757'), ('Renaissance', 'poet')]
# 27

# %% [markdown]
# Final query for this task

# %%
# write your final query
# write your queries
#[('p', 'http://www.wikidata.org/entity/Q37068'), ('name', 'Romanticism')]
#[('p', 'http://www.wikidata.org/entity/Q37853'), ('name', 'Baroque')]
#[('p', 'http://www.wikidata.org/entity/Q4692'), ('name', 'Renaissance')]
#[('NumOf', '156'), ('ocup', 'http://www.wikidata.org/entity/Q1028181'), ('oname', 'painter')]
#[('p', 'http://www.wikidata.org/entity/Q36834'), ('name', 'composer')]
#[('p', 'http://www.wikidata.org/entity/Q1281618'), ('name', 'sculptor')]
#[('p', 'http://www.wikidata.org/entity/Q1028181'), ('name', 'painter')]
#[('p', 'http://www.wikidata.org/entity/Q49757'), ('name', 'poet')]
queryString = """
SELECT  *
WHERE {
    {SELECT DISTINCT (COUNT(?roman) as ?Num) ?ocup (?oname as ?Romanticism)  WHERE
    {
    # ?roman ?obj wd:Q37068;
        wdt:P106 ?ocup.
    # ?roman sc:name ?rname.
    # ?ocup sc:name ?oname.
    FILTER (REGEX(?oname, "sculptor"^^xsd:string) || REGEX(?oname, "composer"^^xsd:string ) || REGEX(?oname, "poet"^^xsd:string ) || REGEX(?oname, "painter"^^xsd:string ))
    #FILTER (REGEX(?oname, "painter"^^xsd:string ))
    #FILTER (?oname = 'sculptor'^^xsd:string || ?oname = 'painter'^^xsd:string) 
    } GROUP BY ?oname ?ocup
    }
    UNION
    {
    select distinct (COUNT(?bar) as ?Num) ?ocup1 (?oname1 as ?Boroque) where
    {
     # ?bar ?obj1 wd:Q37853;
         wdt:P106 ?ocup1.
    #?bar sc:name ?bname.
    # ?ocup1 sc:name ?oname1.
    FILTER (REGEX(?oname1, "sculptor"^^xsd:string ) || REGEX(?oname1, "painter"^^xsd:string ) || REGEX(?oname1, "poet"^^xsd:string)  || REGEX(?oname1, "composer"^^xsd:string ))
    } GROUP BY ?oname1 ?ocup1
    }
    UNION
    {
    select distinct (COUNT(?rena) as ?Num) ?ocup2 ?oname2 as ?Renaissance
    {
     # ?rena ?obj2 wd:Q4692;
         wdt:P106 ?ocup2.
    # ?rena sc:name ?ename.
    # ?ocup2 sc:name ?oname2.
    FILTER (REGEX(?oname2, "sculptor"^^xsd:string ) || REGEX(?oname2, "painter"^^xsd:string ) || REGEX(?oname2, "poet"^^xsd:string)  || REGEX(?oname2, "composer"^^xsd:string ))
    #FILTER (?oname2 = "sculptor"^^xsd:string || ?oname2 = "painter"^^xsd:string) 
   } 
   GROUP BY ?oname2 ?ocup2
   }
   
}  
LIMIT 500
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('Num', '8'), ('ocup', 'http://www.wikidata.org/entity/Q1209498'), ('Romanticism', 'poet lawyer')]
# [('Num', '1'), ('ocup', 'http://www.wikidata.org/entity/Q59938438'), ('Romanticism', 'history painter')]
# [('Num', '7'), ('ocup', 'http://www.wikidata.org/entity/Q21600439'), ('Romanticism', 'landscape painter')]
# [('Num', '21'), ('ocup', 'http://www.wikidata.org/entity/Q36834'), ('Romanticism', 'composer')]
# [('Num', '156'), ('ocup', 'http://www.wikidata.org/entity/Q1028181'), ('Romanticism', 'painter')]
# [('Num', '1'), ('ocup', 'http://www.wikidata.org/entity/Q21680663'), ('Romanticism', 'classical composer')]
# [('Num', '1'), ('ocup', 'http://www.wikidata.org/entity/Q2627699'), ('Romanticism', 'chess composer')]
# [('Num', '159'), ('ocup', 'http://www.wikidata.org/entity/Q49757'), ('Romanticism', 'poet')]
# [('Num', '14'), ('ocup', 'http://www.wikidata.org/entity/Q1281618'), ('Romanticism', 'sculptor')]
# [('Num', '1'), ('ocup1', 'http://www.wikidata.org/entity/Q28947943'), ('Boroque', 'miniature painter')]
# [('Num', '1'), ('ocup1', 'http://www.wikidata.org/entity/Q21600439'), ('Boroque', 'landscape painter')]
# [('Num', '12'), ('ocup1', 'http://www.wikidata.org/entity/Q36834'), ('Boroque', 'composer')]
# [('Num', '388'), ('ocup1', 'http://www.wikidata.org/entity/Q1028181'), ('Boroque', 'painter')]
# [('Num', '3'), ('ocup1', 'http://www.wikidata.org/entity/Q22669155'), ('Boroque', 'fresco painter')]
# [('Num', '1'), ('ocup1', 'http://www.wikidata.org/entity/Q21680663'), ('Boroque', 'classical composer')]
# [('Num', '2'), ('ocup1', 'http://www.wikidata.org/entity/Q1183704'), ('Boroque', 'decorative painter')]
# [('Num', '330'), ('ocup1', 'http://www.wikidata.org/entity/Q1281618'), ('Boroque', 'sculptor')]
# [('Num', '1'), ('ocup1', 'http://www.wikidata.org/entity/Q24056480'), ('Boroque', 'porcelain painter')]
# [('Num', '43'), ('ocup1', 'http://www.wikidata.org/entity/Q49757'), ('Boroque', 'poet')]
# [('Num', '1'), ('ocup1', 'http://www.wikidata.org/entity/Q984276'), ('Boroque', 'court painter')]
# [('Num', '1'), ('ocup1', 'http://www.wikidata.org/entity/Q288728'), ('Boroque', 'painter and varnisher')]
# [('Num', '1'), ('ocup2', 'http://www.wikidata.org/entity/Q1209498'), ('Renaissance', 'poet lawyer')]
# [('Num', '12'), ('ocup2', 'http://www.wikidata.org/entity/Q36834'), ('Renaissance', 'composer')]
# [('Num', '67'), ('ocup2', 'http://www.wikidata.org/entity/Q1028181'), ('Renaissance', 'painter')]
# [('Num', '3'), ('ocup2', 'http://www.wikidata.org/entity/Q22669155'), ('Renaissance', 'fresco painter')]
# [('Num', '26'), ('ocup2', 'http://www.wikidata.org/entity/Q1281618'), ('Renaissance', 'sculptor')]
# [('Num', '16'), ('ocup2', 'http://www.wikidata.org/entity/Q49757'), ('Renaissance', 'poet')]
# 27

# %% [markdown]
# ## Task 5
# Find how many sculptures were made in Italy during Renaissance, Baroque, and Romanticism movements. Please consider all the sculptures and all the sculpture subtypes. (the result set must be a list of triples movement IRI, label and #sculptures).

# %%
# write your queries
#[('p', 'http://www.wikidata.org/entity/Q1281618'), ('name', 'sculptor')]
queryString = """
SELECT DISTINCT ?scul ?sname
WHERE {
     # ?obj1 ?scul wd:Q860861.
    # ?scul sc:name ?sname.
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('scul', 'http://www.wikidata.org/prop/direct/P101'), ('sname', 'field of work')]
# [('scul', 'http://www.wikidata.org/prop/direct/P1056'), ('sname', 'product or material produced')]
# [('scul', 'http://www.wikidata.org/prop/direct/P106'), ('sname', 'occupation')]
# [('scul', 'http://www.wikidata.org/prop/direct/P136'), ('sname', 'genre')]
# [('scul', 'http://www.wikidata.org/prop/direct/P138'), ('sname', 'named after')]
# [('scul', 'http://www.wikidata.org/prop/direct/P144'), ('sname', 'based on')]
# [('scul', 'http://www.wikidata.org/prop/direct/P180'), ('sname', 'depicts')]
# [('scul', 'http://www.wikidata.org/prop/direct/P1889'), ('sname', 'different from')]
# [('scul', 'http://www.wikidata.org/prop/direct/P195'), ('sname', 'collection')]
# [('scul', 'http://www.wikidata.org/prop/direct/P2650'), ('sname', 'interested in')]
# [('scul', 'http://www.wikidata.org/prop/direct/P2670'), ('sname', 'has parts of the class')]
# [('scul', 'http://www.wikidata.org/prop/direct/P279'), ('sname', 'subclass of')]
# [('scul', 'http://www.wikidata.org/prop/direct/P301'), ('sname', "category's main topic")]
# [('scul', 'http://www.wikidata.org/prop/direct/P31'), ('sname', 'instance of')]
# [('scul', 'http://www.wikidata.org/prop/direct/P360'), ('sname', 'is a list of')]
# [('scul', 'http://www.wikidata.org/prop/direct/P361'), ('sname', 'part of')]
# [('scul', 'http://www.wikidata.org/prop/direct/P366'), ('sname', 'use')]
# [('scul', 'http://www.wikidata.org/prop/direct/P4224'), ('sname', 'category contains')]
# [('scul', 'http://www.wikidata.org/prop/direct/P4330'), ('sname', 'contains')]
# [('scul', 'http://www.wikidata.org/prop/direct/P460'), ('sname', 'said to be the same as')]
# [('scul', 'http://www.wikidata.org/prop/direct/P527'), ('sname', 'has part')]
# [('scul', 'http://www.wikidata.org/prop/direct/P800'), ('sname', 'notable work')]
# [('scul', 'http://www.wikidata.org/prop/direct/P912'), ('sname', 'has facility')]
# [('scul', 'http://www.wikidata.org/prop/direct/P921'), ('sname', 'main subject')]
# [('scul', 'http://www.wikidata.org/prop/direct/P971'), ('sname', 'category combines topics')]
# [('scul', 'http://www.wikidata.org/prop/direct/P1074'), ('sname', 'fictional analog of')]
# [('scul', 'http://www.wikidata.org/prop/direct/P8225'), ('sname', 'is metaclass for')]
# 27

# %%
# write your queries
#[('p', 'http://www.wikidata.org/entity/Q37068'), ('name', 'Romanticism')]
#[('p', 'http://www.wikidata.org/entity/Q37853'), ('name', 'Baroque')]
#[('p', 'http://www.wikidata.org/entity/Q4692'), ('name', 'Renaissance')]
#[('NumOf', '156'), ('ocup', 'http://www.wikidata.org/entity/Q1028181'), ('oname', 'painter')]
#[('p', 'http://www.wikidata.org/entity/Q36834'), ('name', 'composer')]
#[('p', 'http://www.wikidata.org/entity/Q1281618'), ('name', 'sculptor')]
#[('p', 'http://www.wikidata.org/entity/Q1028181'), ('name', 'painter')]
#[('p', 'http://www.wikidata.org/entity/Q49757'), ('name', 'poet')]
# write your queries
#[('p', 'http://www.wikidata.org/entity/Q1281618'), ('name', 'sculptor')]
#[('cname', 'http://www.wikidata.org/entity/Q38'), ('m', 'Italy')]
queryString = """
SELECT DISTINCT ?k ?sname
WHERE {
        # ?k wdt:P162 wd:Q38.
        # ?k sc:name ?sname.
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('k', 'http://www.wikidata.org/entity/Q2933446'), ('sname', 'Calabuch')]
# 1

# %%
# write your final query
# write your queries
#[('p', 'http://www.wikidata.org/entity/Q37068'), ('name', 'Romanticism')]
#[('p', 'http://www.wikidata.org/entity/Q37853'), ('name', 'Baroque')]
#[('p', 'http://www.wikidata.org/entity/Q4692'), ('name', 'Renaissance')]
#[('NumOf', '156'), ('ocup', 'http://www.wikidata.org/entity/Q1028181'), ('oname', 'painter')]
#[('p', 'http://www.wikidata.org/entity/Q36834'), ('name', 'composer')]
#[('p', 'http://www.wikidata.org/entity/Q1281618'), ('name', 'sculptor')]
#[('p', 'http://www.wikidata.org/entity/Q1028181'), ('name', 'painter')]
#[('p', 'http://www.wikidata.org/entity/Q49757'), ('name', 'poet')]
queryString = """
SELECT  DISTINCT (COUNT(?roman) as ?Num) ?obj ?rname ?oname ?connection 
WHERE {
    # ?roman ?obj wd:Q37068;
        wdt:P106 wd:Q1281618.
        
      #wd:Q1281618 ?coun wd:Q38.
        
    # ?roman sc:name ?rname.
    # ?obj sc:name ?oname.
   # ?coun sc:name ?connection
     
   }
 
GROUP BY ?obj ?rname ?oname ?connection
LIMIT 500
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('Num', '1'), ('obj', 'http://www.wikidata.org/prop/direct/P135'), ('rname', 'Jean-Baptiste Carpeaux'), ('oname', 'movement')]
# [('Num', '1'), ('obj', 'http://www.wikidata.org/prop/direct/P135'), ('rname', 'Étienne-Jules Ramey'), ('oname', 'movement')]
# [('Num', '1'), ('obj', 'http://www.wikidata.org/prop/direct/P135'), ('rname', 'Constantin Daniel Rosenthal'), ('oname', 'movement')]
# [('Num', '1'), ('obj', 'http://www.wikidata.org/prop/direct/P135'), ('rname', 'Edwin Landseer'), ('oname', 'movement')]
# [('Num', '1'), ('obj', 'http://www.wikidata.org/prop/direct/P135'), ('rname', 'John-Étienne Chaponnière'), ('oname', 'movement')]
# [('Num', '1'), ('obj', 'http://www.wikidata.org/prop/direct/P135'), ('rname', 'Auguste Clésinger'), ('oname', 'movement')]
# [('Num', '1'), ('obj', 'http://www.wikidata.org/prop/direct/P135'), ('rname', 'Eugène Devéria'), ('oname', 'movement')]
# [('Num', '1'), ('obj', 'http://www.wikidata.org/prop/direct/P135'), ('rname', 'Joseph Félon'), ('oname', 'movement')]
# [('Num', '1'), ('obj', 'http://www.wikidata.org/prop/direct/P135'), ('rname', 'Albert Bartholomé'), ('oname', 'movement')]
# [('Num', '1'), ('obj', 'http://www.wikidata.org/prop/direct/P135'), ('rname', 'Antoine Wiertz'), ('oname', 'movement')]
# [('Num', '1'), ('obj', 'http://www.wikidata.org/prop/direct/P135'), ('rname', 'Antonin Moine'), ('oname', 'movement')]
# [('Num', '1'), ('obj', 'http://www.wikidata.org/prop/direct/P135'), ('rname', 'Ary Scheffer'), ('oname', 'movement')]
# [('Num', '1'), ('obj', 'http://www.wikidata.org/prop/direct/P135'), ('rname', 'Théodore Géricault'), ('oname', 'movement')]
# [('Num', '1'), ('obj', 'http://www.wikidata.org/prop/direct/P135'), ('rname', 'Ștefan Ionescu-Valbudea'), ('oname', 'movement')]
# 14

# %%
# write your queries
#[('p', 'http://www.wikidata.org/entity/Q1281618'), ('name', 'sculptor')]
queryString = """
SELECT DISTINCT ?scul ?sname
WHERE {
    # ?scul ?obj wd:Q860861.
    # ?scul sc:name ?sname.
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('scul', 'http://www.wikidata.org/entity/Q2520013'), ('sname', 'sculpture in the round')]
# [('scul', 'http://www.wikidata.org/entity/Q8204840'), ('sname', 'Arqueta de Sant Cugat')]
# [('scul', 'http://www.wikidata.org/entity/Q13723412'), ('sname', 'statue of Sacred Heart of Jesus Christ')]
# [('scul', 'http://www.wikidata.org/entity/Q13723458'), ('sname', 'statue of Sacred Heart of Jesus Christ')]
# [('scul', 'http://www.wikidata.org/entity/Q13723472'), ('sname', 'statue of Sacred Heart of Jesus Christ')]
# [('scul', 'http://www.wikidata.org/entity/Q7982492'), ('sname', 'Wendell Willkie')]
# [('scul', 'http://www.wikidata.org/entity/Q15725481'), ('sname', 'Amar Ekushey')]
# [('scul', 'http://www.wikidata.org/entity/Q15726558'), ('sname', 'Machine with Concrete')]
# [('scul', 'http://www.wikidata.org/entity/Q15726575'), ('sname', 'equestrian statue of Maréchal Foch')]
# [('scul', 'http://www.wikidata.org/entity/Q15732310'), ('sname', 'statue of Sacred Heart of Jesus Christ')]
# [('scul', 'http://www.wikidata.org/entity/Q15876145'), ('sname', 'statue of Sacred Heart of Jesus Christ')]
# [('scul', 'http://www.wikidata.org/entity/Q15876147'), ('sname', 'statue of Sacred Heart of Jesus Christ')]
# [('scul', 'http://www.wikidata.org/entity/Q15876151'), ('sname', 'statue of Sacred Heart of Jesus Christ')]
# [('scul', 'http://www.wikidata.org/entity/Q16008770'), ('sname', 'Cenotaph of Dante Alighieri')]
# [('scul', 'http://www.wikidata.org/entity/Q16013785'), ('sname', 'Font de Santa Eulàlia')]
# [('scul', 'http://www.wikidata.org/entity/Q16060269'), ('sname', 'Blessed Soul')]
# [('scul', 'http://www.wikidata.org/entity/Q46999400'), ('sname', 'Robert E. Lee Monument')]
# [('scul', 'http://www.wikidata.org/entity/Q5212750'), ('sname', 'Damned Soul')]
# [('scul', 'http://www.wikidata.org/entity/Q17033155'), ('sname', 'Three Heads Six Arms')]
# [('scul', 'http://www.wikidata.org/entity/Q17038687'), ('sname', 'Stevie Ray Vaughan Memorial')]
# [('scul', 'http://www.wikidata.org/entity/Q17051597'), ('sname', 'Memoria Urbana Berlin')]
# [('scul', 'http://www.wikidata.org/entity/Q17061947'), ('sname', 'Pangaea')]
# [('scul', 'http://www.wikidata.org/entity/Q17066322'), ('sname', 'William the Silent')]
# [('scul', 'http://www.wikidata.org/entity/Q17080367'), ('sname', 'Monument to Effort')]
# [('scul', 'http://www.wikidata.org/entity/Q17194246'), ('sname', 'William Shakespeare')]
# [('scul', 'http://www.wikidata.org/entity/Q17202021'), ('sname', 'Bust of Linnaeus, Hartekamp')]
# [('scul', 'http://www.wikidata.org/entity/Q85763829'), ('sname', 'Godzilla head')]
# [('scul', 'http://www.wikidata.org/entity/Q17300630'), ('sname', 'Le Combat du duc de Clarence by Émilien de Nieuwerkerke')]
# [('scul', 'http://www.wikidata.org/entity/Q17302062'), ('sname', 'Relief of the Rapture of Saint Ignatius from the Holy Cave of Manresa')]
# [('scul', 'http://www.wikidata.org/entity/Q17320331'), ('sname', 'Still Life with Fruit')]
# [('scul', 'http://www.wikidata.org/entity/Q17320510'), ('sname', 'Santa Maria del Parto a Mergellina - Presepe Giovanni da Nola')]
# [('scul', 'http://www.wikidata.org/entity/Q17339379'), ('sname', 'Fontein Vismarkt, Leiden')]
# [('scul', 'http://www.wikidata.org/entity/Q17347007'), ('sname', "De l'en-dessous")]
# [('scul', 'http://www.wikidata.org/entity/Q17452741'), ('sname', 'Eijsden Castle: sculpture group with peacocks')]
# [('scul', 'http://www.wikidata.org/entity/Q17490497'), ('sname', 'La lechera (sculpture)')]
# [('scul', 'http://www.wikidata.org/entity/Q17490530'), ('sname', 'Memorial to Ramón Pérez de Ayala')]
# [('scul', 'http://www.wikidata.org/entity/Q17490551'), ('sname', 'Memorial of Rafael del Riego')]
# [('scul', 'http://www.wikidata.org/entity/Q17496295'), ('sname', 'Memorial to Ramón Pérez de Ayala')]
# [('scul', 'http://www.wikidata.org/entity/Q17509360'), ('sname', 'Benito Juárez')]
# [('scul', 'http://www.wikidata.org/entity/Q4404699'), ('sname', 'garden sculpture')]
# [('scul', 'http://www.wikidata.org/entity/Q17581109'), ('sname', 'La femme au paon by Falguière-Ra 960')]
# [('scul', 'http://www.wikidata.org/entity/Q17588604'), ('sname', 'Caçador de lleons')]
# [('scul', 'http://www.wikidata.org/entity/Q17607118'), ('sname', 'Slotklooster: bust of Arnold Janssen')]
# [('scul', 'http://www.wikidata.org/entity/Q17609601'), ('sname', 'Europa en Afrika')]
# [('scul', 'http://www.wikidata.org/entity/Q17626342'), ('sname', 'John of Nepomuk statue in Bystrzyca Kłodzka')]
# [('scul', 'http://www.wikidata.org/entity/Q17627668'), ('sname', 'Brutalitätenskulptur')]
# [('scul', 'http://www.wikidata.org/entity/Q17627671'), ('sname', 'YP 1')]
# [('scul', 'http://www.wikidata.org/entity/Q17627676'), ('sname', 'Recovered Memory')]
# [('scul', 'http://www.wikidata.org/entity/Q17627684'), ('sname', '46 Charred Steps')]
# [('scul', 'http://www.wikidata.org/entity/Q17629542'), ('sname', 'Endymion sleeping')]
# [('scul', 'http://www.wikidata.org/entity/Q17638098'), ('sname', 'Retable de Naves')]
# [('scul', 'http://www.wikidata.org/entity/Q4319509'), ('sname', 'Gedenknaald Baarn')]
# [('scul', 'http://www.wikidata.org/entity/Q11922308'), ('sname', "Font d'Hèrcules")]
# [('scul', 'http://www.wikidata.org/entity/Q18084708'), ('sname', 'Trowel II')]
# [('scul', 'http://www.wikidata.org/entity/Q18084711'), ('sname', 'Crusoe Umbrella')]
# [('scul', 'http://www.wikidata.org/entity/Q18084737'), ('sname', 'Saw, Sawing')]
# [('scul', 'http://www.wikidata.org/entity/Q18084738'), ('sname', 'Torn Notebook')]
# [('scul', 'http://www.wikidata.org/entity/Q18085992'), ('sname', 'statue of Sacred Heart of Jesus Christ')]
# [('scul', 'http://www.wikidata.org/entity/Q18123493'), ('sname', 'A Pau Casals')]
# [('scul', 'http://www.wikidata.org/entity/Q18144845'), ('sname', "L'Amour à la folie")]
# [('scul', 'http://www.wikidata.org/entity/Q18148326'), ('sname', 'Daniel Webster')]
# [('scul', 'http://www.wikidata.org/entity/Q18150038'), ('sname', 'February One')]
# [('scul', 'http://www.wikidata.org/entity/Q18160018'), ('sname', 'Ecstasy')]
# [('scul', 'http://www.wikidata.org/entity/Q3007583'), ('sname', "Cupid's Span")]
# [('scul', 'http://www.wikidata.org/entity/Q3476515'), ('sname', 'architectural sculpture')]
# [('scul', 'http://www.wikidata.org/entity/Q19298700'), ('sname', 'Maraş lion')]
# [('scul', 'http://www.wikidata.org/entity/Q19312121'), ('sname', 'Zur Schicht')]
# [('scul', 'http://www.wikidata.org/entity/Q19336295'), ('sname', 'Sleep')]
# [('scul', 'http://www.wikidata.org/entity/Q19338532'), ('sname', 'Monument to Michael the Brave')]
# [('scul', 'http://www.wikidata.org/entity/Q6063200'), ('sname', 'Hygieia-Brunnen, Hamburg')]
# [('scul', 'http://www.wikidata.org/entity/Q20971124'), ('sname', 'Mirabeau répondant à Dreux-Brézé')]
# [('scul', 'http://www.wikidata.org/entity/Q20972971'), ('sname', 'Equestrian Statue of Louis Botha')]
# [('scul', 'http://www.wikidata.org/entity/Q21006153'), ('sname', 'The Completion of the Louvre. The Emperor Approving the Plans Presented by Monsieur Visconti.')]
# [('scul', 'http://www.wikidata.org/entity/Q21011370'), ('sname', 'Fountain with Kneeling Youths')]
# [('scul', 'http://www.wikidata.org/entity/Q21011679'), ('sname', 'Fountain of Kneeling Youths')]
# [('scul', 'http://www.wikidata.org/entity/Q21012006'), ('sname', 'Fountain of Kneeling Youths')]
# [('scul', 'http://www.wikidata.org/entity/Q21016110'), ('sname', 'The Pioneer Mother Memorial')]
# [('scul', 'http://www.wikidata.org/entity/Q21016187'), ('sname', 'Singing Sky')]
# [('scul', 'http://www.wikidata.org/entity/Q56070905'), ('sname', 'Girl with Goat')]
# [('scul', 'http://www.wikidata.org/entity/Q21644037'), ('sname', "Fenêtre de l'hôtel Béringuier-Maynier")]
# [('scul', 'http://www.wikidata.org/entity/Q21648015'), ('sname', 'Solidarity')]
# [('scul', 'http://www.wikidata.org/entity/Q21648040'), ('sname', 'The Docker')]
# [('scul', 'http://www.wikidata.org/entity/Q21648552'), ('sname', 'Omaggio al cosmonauta')]
# [('scul', 'http://www.wikidata.org/entity/Q21777312'), ('sname', 'Quand même')]
# [('scul', 'http://www.wikidata.org/entity/Q21979792'), ('sname', 'Savacou')]
# [('scul', 'http://www.wikidata.org/entity/Q22022317'), ('sname', 'Decanter')]
# [('scul', 'http://www.wikidata.org/entity/Q22022599'), ('sname', 'George Washington')]
# [('scul', 'http://www.wikidata.org/entity/Q22025936'), ('sname', 'Velosaurus')]
# [('scul', 'http://www.wikidata.org/entity/Q22075395'), ('sname', 'Sappho sleeping')]
# [('scul', 'http://www.wikidata.org/entity/Q22075450'), ('sname', 'Mermaid')]
# [('scul', 'http://www.wikidata.org/entity/Q22080797'), ('sname', 'The Martyrdom of Saint Sebastian')]
# [('scul', 'http://www.wikidata.org/entity/Q22080834'), ('sname', 'The Adoration of the Magi')]
# [('scul', 'http://www.wikidata.org/entity/Q22081095'), ('sname', 'Human Passions')]
# [('scul', 'http://www.wikidata.org/entity/Q22081772'), ('sname', 'Madonna with Censing Angels')]
# [('scul', 'http://www.wikidata.org/entity/Q22081808'), ('sname', 'The Virgin and Child')]
# [('scul', 'http://www.wikidata.org/entity/Q22081824'), ('sname', 'The Faint of Mary and The Descent from the Cross (fragment of a retable group)')]
# [('scul', 'http://www.wikidata.org/entity/Q22085367'), ('sname', 'The great Relic Bearer')]
# [('scul', 'http://www.wikidata.org/entity/Q22241733'), ('sname', 'The Prodigal Son')]
# [('scul', 'http://www.wikidata.org/entity/Q22245571'), ('sname', 'Mother Grieving over her Dead Child')]
# [('scul', 'http://www.wikidata.org/entity/Q22246417'), ('sname', 'The Holy Women at the Tomb')]
# 100

# %% [markdown]
# Final query for this task

# %% [markdown]
# There is no any data of sculptures where it made .

# %%
# write your final query
# write your queries
#[('p', 'http://www.wikidata.org/entity/Q1281618'), ('name', 'sculptor')]
queryString = """
SELECT DISTINCT ?scul ?sname
WHERE {
    # ?scul ?obj wd:Q860861.
    # ?scul sc:name ?sname.
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)

# %% [markdown]
# ## Task 6
# For each European country find how many poets belong to Romanticism (the result set must be a list of triples country IRI, label and #poets).

# %%
#Using Europe BGP from other task 
#[('p', 'http://www.wikidata.org/entity/Q46'), ('name', 'Europe')]
queryString = """
SELECT DISTINCT ?cname ?m 
WHERE {
   # bind something
     wd:Q46 wdt:P527 ?p.
     # ?p wdt:P527 ?cname.
   # get the label
   #?pn sc:name ?pname.
   # ?cname sc:name ?m.
}
LIMIT 200
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('cname', 'http://www.wikidata.org/entity/Q1410'), ('m', 'Gibraltar')]
# [('cname', 'http://www.wikidata.org/entity/Q142'), ('m', 'France')]
# [('cname', 'http://www.wikidata.org/entity/Q145'), ('m', 'United Kingdom')]
# [('cname', 'http://www.wikidata.org/entity/Q183'), ('m', 'Germany')]
# [('cname', 'http://www.wikidata.org/entity/Q184'), ('m', 'Belarus')]
# [('cname', 'http://www.wikidata.org/entity/Q189'), ('m', 'Iceland')]
# [('cname', 'http://www.wikidata.org/entity/Q191'), ('m', 'Estonia')]
# [('cname', 'http://www.wikidata.org/entity/Q20'), ('m', 'Norway')]
# [('cname', 'http://www.wikidata.org/entity/Q211'), ('m', 'Latvia')]
# [('cname', 'http://www.wikidata.org/entity/Q212'), ('m', 'Ukraine')]
# [('cname', 'http://www.wikidata.org/entity/Q213'), ('m', 'Czech Republic')]
# [('cname', 'http://www.wikidata.org/entity/Q214'), ('m', 'Slovakia')]
# [('cname', 'http://www.wikidata.org/entity/Q215'), ('m', 'Slovenia')]
# [('cname', 'http://www.wikidata.org/entity/Q217'), ('m', 'Moldova')]
# [('cname', 'http://www.wikidata.org/entity/Q218'), ('m', 'Romania')]
# [('cname', 'http://www.wikidata.org/entity/Q219'), ('m', 'Bulgaria')]
# [('cname', 'http://www.wikidata.org/entity/Q221'), ('m', 'North Macedonia')]
# [('cname', 'http://www.wikidata.org/entity/Q222'), ('m', 'Albania')]
# [('cname', 'http://www.wikidata.org/entity/Q224'), ('m', 'Croatia')]
# [('cname', 'http://www.wikidata.org/entity/Q225'), ('m', 'Bosnia and Herzegovina')]
# [('cname', 'http://www.wikidata.org/entity/Q228'), ('m', 'Andorra')]
# [('cname', 'http://www.wikidata.org/entity/Q233'), ('m', 'Malta')]
# [('cname', 'http://www.wikidata.org/entity/Q235'), ('m', 'Monaco')]
# [('cname', 'http://www.wikidata.org/entity/Q236'), ('m', 'Montenegro')]
# [('cname', 'http://www.wikidata.org/entity/Q237'), ('m', 'Vatican City')]
# [('cname', 'http://www.wikidata.org/entity/Q238'), ('m', 'San Marino')]
# [('cname', 'http://www.wikidata.org/entity/Q25230'), ('m', 'Guernsey')]
# [('cname', 'http://www.wikidata.org/entity/Q27'), ('m', 'Ireland')]
# [('cname', 'http://www.wikidata.org/entity/Q28'), ('m', 'Hungary')]
# [('cname', 'http://www.wikidata.org/entity/Q29'), ('m', 'Spain')]
# [('cname', 'http://www.wikidata.org/entity/Q31'), ('m', 'Belgium')]
# [('cname', 'http://www.wikidata.org/entity/Q32'), ('m', 'Luxembourg')]
# [('cname', 'http://www.wikidata.org/entity/Q33'), ('m', 'Finland')]
# [('cname', 'http://www.wikidata.org/entity/Q34'), ('m', 'Sweden')]
# [('cname', 'http://www.wikidata.org/entity/Q347'), ('m', 'Liechtenstein')]
# [('cname', 'http://www.wikidata.org/entity/Q35'), ('m', 'Denmark')]
# [('cname', 'http://www.wikidata.org/entity/Q36'), ('m', 'Poland')]
# [('cname', 'http://www.wikidata.org/entity/Q37'), ('m', 'Lithuania')]
# [('cname', 'http://www.wikidata.org/entity/Q38'), ('m', 'Italy')]
# [('cname', 'http://www.wikidata.org/entity/Q39'), ('m', 'Switzerland')]
# [('cname', 'http://www.wikidata.org/entity/Q40'), ('m', 'Austria')]
# [('cname', 'http://www.wikidata.org/entity/Q403'), ('m', 'Serbia')]
# [('cname', 'http://www.wikidata.org/entity/Q41'), ('m', 'Greece')]
# [('cname', 'http://www.wikidata.org/entity/Q45'), ('m', 'Portugal')]
# [('cname', 'http://www.wikidata.org/entity/Q4628'), ('m', 'Faroe Islands')]
# [('cname', 'http://www.wikidata.org/entity/Q55'), ('m', 'Netherlands')]
# [('cname', 'http://www.wikidata.org/entity/Q785'), ('m', 'Jersey')]
# [('cname', 'http://www.wikidata.org/entity/Q875134'), ('m', 'European Russia')]
# [('cname', 'http://www.wikidata.org/entity/Q9676'), ('m', 'Isle of Man')]
# [('cname', 'http://www.wikidata.org/entity/Q3405693'), ('m', 'Sark')]
# [('cname', 'http://www.wikidata.org/entity/Q5689'), ('m', 'Åland')]
# [('cname', 'http://www.wikidata.org/entity/Q842829'), ('m', 'Svalbard and Jan Mayen')]
# [('cname', 'http://www.wikidata.org/entity/Q19715270'), ('m', 'European Kazakhstan')]
# 53

# %%
#BGP of poets for exploring

queryString = """
SELECT DISTINCT ?poet ?poname
WHERE {
   # bind something
     # ?poet ?o wd:Q49757.
    # ?poet sc:name ?poname.
}
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('poet', 'http://www.wikidata.org/entity/Q1373516'), ('poname', 'Eugénio de Castro')]
# [('poet', 'http://www.wikidata.org/entity/Q589406'), ('poname', 'Empress Xiaoquancheng')]
# [('poet', 'http://www.wikidata.org/entity/Q610608'), ('poname', 'António Aleixo')]
# [('poet', 'http://www.wikidata.org/entity/Q710504'), ('poname', 'Bohuslav Balbín')]
# [('poet', 'http://www.wikidata.org/entity/Q8188119'), ('poname', 'Adelina Lopes Vieira')]
# [('poet', 'http://www.wikidata.org/entity/Q8201526'), ('poname', 'Antonio Márquez Salas')]
# [('poet', 'http://www.wikidata.org/entity/Q8201629'), ('poname', 'Antonio Rendic')]
# [('poet', 'http://www.wikidata.org/entity/Q8202094'), ('poname', 'Antônio de Castro Assumpção')]
# [('poet', 'http://www.wikidata.org/entity/Q8246828'), ('poname', 'Bernat Català de Valleriola')]
# [('poet', 'http://www.wikidata.org/entity/Q1191225'), ('poname', 'Tan Sitong')]
# [('poet', 'http://www.wikidata.org/entity/Q4790571'), ('poname', 'Arifin C. Noer')]
# [('poet', 'http://www.wikidata.org/entity/Q57257'), ('poname', 'Peter Cornelius')]
# [('poet', 'http://www.wikidata.org/entity/Q6143494'), ('poname', 'Lin Xu')]
# [('poet', 'http://www.wikidata.org/entity/Q8353951'), ('poname', 'Darío Herrera Peo')]
# [('poet', 'http://www.wikidata.org/entity/Q8447800'), ('poname', 'Xavier Rodríguez Barrio')]
# [('poet', 'http://www.wikidata.org/entity/Q8462536'), ('poname', 'Hsu Fang')]
# [('poet', 'http://www.wikidata.org/entity/Q8463086'), ('poname', "Chang Ch'ung-ho")]
# [('poet', 'http://www.wikidata.org/entity/Q159967'), ('poname', 'Augusto Roa Bastos')]
# [('poet', 'http://www.wikidata.org/entity/Q219862'), ('poname', 'Raymond Carver')]
# [('poet', 'http://www.wikidata.org/entity/Q231708'), ('poname', 'Edith Nesbit')]
# 20

# %%
#Exploring single poet

queryString = """
SELECT DISTINCT ?poet ?poname
WHERE {
   # bind something
    wd:Q231708 ?poet ?o.
    # ?poet sc:name ?poname.
}
LIMIT 200
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('poet', 'http://www.wikidata.org/prop/direct/P1005'), ('poname', 'Portuguese National Library ID')]
# [('poet', 'http://www.wikidata.org/prop/direct/P1006'), ('poname', 'Nationale Thesaurus voor Auteurs ID')]
# [('poet', 'http://www.wikidata.org/prop/direct/P1015'), ('poname', 'NORAF ID')]
# [('poet', 'http://www.wikidata.org/prop/direct/P1038'), ('poname', 'relative')]
# [('poet', 'http://www.wikidata.org/prop/direct/P106'), ('poname', 'occupation')]
# [('poet', 'http://www.wikidata.org/prop/direct/P119'), ('poname', 'place of burial')]
# [('poet', 'http://www.wikidata.org/prop/direct/P1196'), ('poname', 'manner of death')]
# [('poet', 'http://www.wikidata.org/prop/direct/P1207'), ('poname', 'NUKAT ID')]
# [('poet', 'http://www.wikidata.org/prop/direct/P1233'), ('poname', 'Internet Speculative Fiction Database author ID')]
# [('poet', 'http://www.wikidata.org/prop/direct/P1263'), ('poname', 'NNDB people ID')]
# [('poet', 'http://www.wikidata.org/prop/direct/P1273'), ('poname', 'CANTIC ID')]
# [('poet', 'http://www.wikidata.org/prop/direct/P1280'), ('poname', 'CONOR.SI ID')]
# [('poet', 'http://www.wikidata.org/prop/direct/P1309'), ('poname', 'EGAXA ID')]
# [('poet', 'http://www.wikidata.org/prop/direct/P1315'), ('poname', 'NLA Trove ID')]
# [('poet', 'http://www.wikidata.org/prop/direct/P1343'), ('poname', 'described by source')]
# [('poet', 'http://www.wikidata.org/prop/direct/P1412'), ('poname', 'languages spoken, written or signed')]
# [('poet', 'http://www.wikidata.org/prop/direct/P1415'), ('poname', 'Oxford Dictionary of National Biography ID')]
# [('poet', 'http://www.wikidata.org/prop/direct/P1417'), ('poname', 'Encyclopædia Britannica Online ID')]
# [('poet', 'http://www.wikidata.org/prop/direct/P1430'), ('poname', 'OpenPlaques subject ID')]
# [('poet', 'http://www.wikidata.org/prop/direct/P1472'), ('poname', 'Commons Creator page')]
# [('poet', 'http://www.wikidata.org/prop/direct/P1477'), ('poname', 'birth name')]
# [('poet', 'http://www.wikidata.org/prop/direct/P1559'), ('poname', 'name in native language')]
# [('poet', 'http://www.wikidata.org/prop/direct/P1580'), ('poname', 'University of Barcelona authority ID')]
# [('poet', 'http://www.wikidata.org/prop/direct/P1695'), ('poname', 'NLP ID (unique)')]
# [('poet', 'http://www.wikidata.org/prop/direct/P18'), ('poname', 'image')]
# [('poet', 'http://www.wikidata.org/prop/direct/P1816'), ('poname', 'National Portrait Gallery (London) person ID')]
# [('poet', 'http://www.wikidata.org/prop/direct/P1899'), ('poname', 'LibriVox author ID')]
# [('poet', 'http://www.wikidata.org/prop/direct/P19'), ('poname', 'place of birth')]
# [('poet', 'http://www.wikidata.org/prop/direct/P1938'), ('poname', 'Project Gutenberg author ID')]
# [('poet', 'http://www.wikidata.org/prop/direct/P1953'), ('poname', 'Discogs artist ID')]
# [('poet', 'http://www.wikidata.org/prop/direct/P20'), ('poname', 'place of death')]
# [('poet', 'http://www.wikidata.org/prop/direct/P2031'), ('poname', 'work period (start)')]
# [('poet', 'http://www.wikidata.org/prop/direct/P21'), ('poname', 'sex or gender')]
# [('poet', 'http://www.wikidata.org/prop/direct/P213'), ('poname', 'ISNI')]
# [('poet', 'http://www.wikidata.org/prop/direct/P214'), ('poname', 'VIAF ID')]
# [('poet', 'http://www.wikidata.org/prop/direct/P2163'), ('poname', 'FAST ID')]
# [('poet', 'http://www.wikidata.org/prop/direct/P2191'), ('poname', 'Vegetti Catalog of Fantastic Literature NILF ID')]
# [('poet', 'http://www.wikidata.org/prop/direct/P22'), ('poname', 'father')]
# [('poet', 'http://www.wikidata.org/prop/direct/P227'), ('poname', 'GND ID')]
# [('poet', 'http://www.wikidata.org/prop/direct/P244'), ('poname', 'Library of Congress authority ID')]
# [('poet', 'http://www.wikidata.org/prop/direct/P2533'), ('poname', 'WomenWriters ID')]
# [('poet', 'http://www.wikidata.org/prop/direct/P26'), ('poname', 'spouse')]
# [('poet', 'http://www.wikidata.org/prop/direct/P2600'), ('poname', 'Geni.com profile ID')]
# [('poet', 'http://www.wikidata.org/prop/direct/P268'), ('poname', 'Bibliothèque nationale de France ID')]
# [('poet', 'http://www.wikidata.org/prop/direct/P269'), ('poname', 'IdRef ID')]
# [('poet', 'http://www.wikidata.org/prop/direct/P27'), ('poname', 'country of citizenship')]
# [('poet', 'http://www.wikidata.org/prop/direct/P2799'), ('poname', 'BVMC person ID')]
# [('poet', 'http://www.wikidata.org/prop/direct/P2949'), ('poname', 'WikiTree person ID')]
# [('poet', 'http://www.wikidata.org/prop/direct/P2966'), ('poname', 'National Library of Wales Authority ID')]
# [('poet', 'http://www.wikidata.org/prop/direct/P3029'), ('poname', 'UK National Archives ID')]
# [('poet', 'http://www.wikidata.org/prop/direct/P31'), ('poname', 'instance of')]
# [('poet', 'http://www.wikidata.org/prop/direct/P3154'), ('poname', 'Runeberg author ID')]
# [('poet', 'http://www.wikidata.org/prop/direct/P3222'), ('poname', 'NE.se ID')]
# [('poet', 'http://www.wikidata.org/prop/direct/P3348'), ('poname', 'National Library of Greece ID')]
# [('poet', 'http://www.wikidata.org/prop/direct/P3373'), ('poname', 'sibling')]
# [('poet', 'http://www.wikidata.org/prop/direct/P3430'), ('poname', 'SNAC ARK ID')]
# [('poet', 'http://www.wikidata.org/prop/direct/P345'), ('poname', 'IMDb ID')]
# [('poet', 'http://www.wikidata.org/prop/direct/P349'), ('poname', 'National Diet Library ID')]
# [('poet', 'http://www.wikidata.org/prop/direct/P3630'), ('poname', 'Babelio author ID')]
# [('poet', 'http://www.wikidata.org/prop/direct/P373'), ('poname', 'Commons category')]
# [('poet', 'http://www.wikidata.org/prop/direct/P3762'), ('poname', 'openMLOL author ID')]
# [('poet', 'http://www.wikidata.org/prop/direct/P396'), ('poname', 'SBN author ID')]
# [('poet', 'http://www.wikidata.org/prop/direct/P3987'), ('poname', 'SHARE Catalogue author ID')]
# [('poet', 'http://www.wikidata.org/prop/direct/P409'), ('poname', 'Libraries Australia ID')]
# [('poet', 'http://www.wikidata.org/prop/direct/P434'), ('poname', 'MusicBrainz artist ID')]
# [('poet', 'http://www.wikidata.org/prop/direct/P4342'), ('poname', 'Store norske leksikon ID')]
# [('poet', 'http://www.wikidata.org/prop/direct/P4431'), ('poname', 'Google Doodle')]
# [('poet', 'http://www.wikidata.org/prop/direct/P4457'), ('poname', 'DAHR artist ID')]
# [('poet', 'http://www.wikidata.org/prop/direct/P4629'), ('poname', 'Online Books Page author ID')]
# [('poet', 'http://www.wikidata.org/prop/direct/P463'), ('poname', 'member of')]
# [('poet', 'http://www.wikidata.org/prop/direct/P4985'), ('poname', 'TMDb person ID')]
# [('poet', 'http://www.wikidata.org/prop/direct/P5034'), ('poname', 'National Library of Korea ID')]
# [('poet', 'http://www.wikidata.org/prop/direct/P535'), ('poname', 'Find A Grave memorial ID')]
# [('poet', 'http://www.wikidata.org/prop/direct/P5357'), ('poname', 'The Encyclopedia of Science Fiction ID')]
# [('poet', 'http://www.wikidata.org/prop/direct/P5392'), ('poname', 'Poetry Archive poet ID')]
# [('poet', 'http://www.wikidata.org/prop/direct/P5478'), ('poname', 'RPO poet ID')]
# [('poet', 'http://www.wikidata.org/prop/direct/P5570'), ('poname', 'NooSFere author ID')]
# [('poet', 'http://www.wikidata.org/prop/direct/P5587'), ('poname', 'Libris-URI')]
# [('poet', 'http://www.wikidata.org/prop/direct/P569'), ('poname', 'date of birth')]
# [('poet', 'http://www.wikidata.org/prop/direct/P570'), ('poname', 'date of death')]
# [('poet', 'http://www.wikidata.org/prop/direct/P5705'), ('poname', 'Los Angeles Review of Books author ID')]
# [('poet', 'http://www.wikidata.org/prop/direct/P6104'), ('poname', 'maintained by WikiProject')]
# [('poet', 'http://www.wikidata.org/prop/direct/P646'), ('poname', 'Freebase ID')]
# [('poet', 'http://www.wikidata.org/prop/direct/P648'), ('poname', 'Open Library ID')]
# [('poet', 'http://www.wikidata.org/prop/direct/P6683'), ('poname', 'Alexander Turnbull Library ID')]
# [('poet', 'http://www.wikidata.org/prop/direct/P6706'), ('poname', 'De Agostini ID')]
# [('poet', 'http://www.wikidata.org/prop/direct/P6722'), ('poname', 'FemBio ID')]
# [('poet', 'http://www.wikidata.org/prop/direct/P6745'), ('poname', 'Orlando author ID')]
# [('poet', 'http://www.wikidata.org/prop/direct/P6886'), ('poname', 'writing language')]
# [('poet', 'http://www.wikidata.org/prop/direct/P691'), ('poname', 'NKCR AUT ID')]
# [('poet', 'http://www.wikidata.org/prop/direct/P6984'), ('poname', 'Rupa Publications author ID')]
# [('poet', 'http://www.wikidata.org/prop/direct/P723'), ('poname', 'Digitale Bibliotheek voor de Nederlandse Letteren author ID')]
# [('poet', 'http://www.wikidata.org/prop/direct/P7293'), ('poname', 'PLWABN ID')]
# [('poet', 'http://www.wikidata.org/prop/direct/P734'), ('poname', 'family name')]
# [('poet', 'http://www.wikidata.org/prop/direct/P735'), ('poname', 'given name')]
# [('poet', 'http://www.wikidata.org/prop/direct/P742'), ('poname', 'pseudonym')]
# [('poet', 'http://www.wikidata.org/prop/direct/P7578'), ('poname', 'DUC ID')]
# [('poet', 'http://www.wikidata.org/prop/direct/P7704'), ('poname', 'Europeana entity')]
# [('poet', 'http://www.wikidata.org/prop/direct/P7859'), ('poname', 'WorldCat Identities ID')]
# [('poet', 'http://www.wikidata.org/prop/direct/P7902'), ('poname', 'Deutsche Biographie (GND) ID')]
# [('poet', 'http://www.wikidata.org/prop/direct/P800'), ('poname', 'notable work')]
# [('poet', 'http://www.wikidata.org/prop/direct/P8234'), ('poname', 'LiederNet author ID')]
# [('poet', 'http://www.wikidata.org/prop/direct/P856'), ('poname', 'official website')]
# [('poet', 'http://www.wikidata.org/prop/direct/P866'), ('poname', 'Perlentaucher ID')]
# [('poet', 'http://www.wikidata.org/prop/direct/P8849'), ('poname', 'CONOR.BG ID')]
# [('poet', 'http://www.wikidata.org/prop/direct/P8870'), ('poname', 'Hyperion Records person ID')]
# [('poet', 'http://www.wikidata.org/prop/direct/P8980'), ('poname', 'KANTO ID')]
# [('poet', 'http://www.wikidata.org/prop/direct/P906'), ('poname', 'SELIBR ID')]
# [('poet', 'http://www.wikidata.org/prop/direct/P9251'), ('poname', 'Cyprus University of Technology ID')]
# [('poet', 'http://www.wikidata.org/prop/direct/P9287'), ('poname', 'Cyprus Bibliography ID')]
# [('poet', 'http://www.wikidata.org/prop/direct/P9459'), ('poname', 'Rekhta author ID')]
# [('poet', 'http://www.wikidata.org/prop/direct/P949'), ('poname', 'National Library of Israel ID')]
# [('poet', 'http://www.wikidata.org/prop/direct/P950'), ('poname', 'Biblioteca Nacional de España ID')]
# [('poet', 'http://www.wikidata.org/prop/direct/P9686'), ('poname', 'Classical Archives composer ID')]
# [('poet', 'http://www.wikidata.org/prop/direct/P8085'), ('poname', 'Curran Index contributor ID')]
# [('poet', 'http://www.wikidata.org/prop/direct/P7504'), ('poname', 'Jeugdliteratuur ID')]
# [('poet', 'http://www.wikidata.org/prop/direct/P1564'), ('poname', 'At the Circulating Library ID')]
# 117

# %%
#Using country of citizenship P27 for getting country of poets working for Romanticism
#Q37068 - Romanticism
#Q49757 - Poet
queryString = """
SELECT DISTINCT ?poet ?poname ?coc ?cname
WHERE {
   # bind something
   # ?poet ?obj wd:Q37068;
   wdt:P106 wd:Q49757;
    wdt:P27 ?coc.
    # ?poet sc:name ?poname.
    # ?coc sc:name ?cname.
}
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('poet', 'http://www.wikidata.org/entity/Q5932129'), ('poname', 'Joaquín José Cervino'), ('coc', 'http://www.wikidata.org/entity/Q29'), ('cname', 'Spain')]
# [('poet', 'http://www.wikidata.org/entity/Q5258787'), ('poname', 'Tobias Barreto'), ('coc', 'http://www.wikidata.org/entity/Q155'), ('cname', 'Brazil')]
# [('poet', 'http://www.wikidata.org/entity/Q5340521'), ('poname', 'Eduardo Asquerino'), ('coc', 'http://www.wikidata.org/entity/Q29'), ('cname', 'Spain')]
# [('poet', 'http://www.wikidata.org/entity/Q573223'), ('poname', 'Patricio de la Escosura'), ('coc', 'http://www.wikidata.org/entity/Q29'), ('cname', 'Spain')]
# [('poet', 'http://www.wikidata.org/entity/Q688529'), ('poname', 'Johannes Carsten Hauch'), ('coc', 'http://www.wikidata.org/entity/Q35'), ('cname', 'Denmark')]
# [('poet', 'http://www.wikidata.org/entity/Q597298'), ('poname', 'Antoni Edward Odyniec'), ('coc', 'http://www.wikidata.org/entity/Q34266'), ('cname', 'Russian Empire')]
# [('poet', 'http://www.wikidata.org/entity/Q645491'), ('poname', 'Yevhen Hrebinka'), ('coc', 'http://www.wikidata.org/entity/Q34266'), ('cname', 'Russian Empire')]
# [('poet', 'http://www.wikidata.org/entity/Q93343'), ('poname', 'Percy Bysshe Shelley'), ('coc', 'http://www.wikidata.org/entity/Q161885'), ('cname', 'Great Britain')]
# [('poet', 'http://www.wikidata.org/entity/Q93343'), ('poname', 'Percy Bysshe Shelley'), ('coc', 'http://www.wikidata.org/entity/Q174193'), ('cname', 'United Kingdom of Great Britain and Ireland')]
# [('poet', 'http://www.wikidata.org/entity/Q378133'), ('poname', 'Hendrik Conscience'), ('coc', 'http://www.wikidata.org/entity/Q31'), ('cname', 'Belgium')]
# [('poet', 'http://www.wikidata.org/entity/Q352914'), ('poname', 'Karel Jaromír Erben'), ('coc', 'http://www.wikidata.org/entity/Q131964'), ('cname', 'Austrian Empire')]
# [('poet', 'http://www.wikidata.org/entity/Q352914'), ('poname', 'Karel Jaromír Erben'), ('coc', 'http://www.wikidata.org/entity/Q28513'), ('cname', 'Austria-Hungary')]
# [('poet', 'http://www.wikidata.org/entity/Q2621545'), ('poname', 'Alexander Polezhayev'), ('coc', 'http://www.wikidata.org/entity/Q34266'), ('cname', 'Russian Empire')]
# [('poet', 'http://www.wikidata.org/entity/Q4151323'), ('poname', 'Eduard Huber'), ('coc', 'http://www.wikidata.org/entity/Q34266'), ('cname', 'Russian Empire')]
# [('poet', 'http://www.wikidata.org/entity/Q60684'), ('poname', 'Novalis'), ('coc', 'http://www.wikidata.org/entity/Q156199'), ('cname', 'Electorate of Saxony')]
# [('poet', 'http://www.wikidata.org/entity/Q761705'), ('poname', 'Louis Bouilhet'), ('coc', 'http://www.wikidata.org/entity/Q142'), ('cname', 'France')]
# [('poet', 'http://www.wikidata.org/entity/Q2980553'), ('poname', 'Antoinette Henriette Clémence Robert'), ('coc', 'http://www.wikidata.org/entity/Q142'), ('cname', 'France')]
# [('poet', 'http://www.wikidata.org/entity/Q27179260'), ('poname', 'Alexandre de Saint-Juan'), ('coc', 'http://www.wikidata.org/entity/Q142'), ('cname', 'France')]
# [('poet', 'http://www.wikidata.org/entity/Q49767'), ('poname', 'François-René de Chateaubriand'), ('coc', 'http://www.wikidata.org/entity/Q142'), ('cname', 'France')]
# [('poet', 'http://www.wikidata.org/entity/Q64652'), ('poname', 'Gaspar Núñez de Arce'), ('coc', 'http://www.wikidata.org/entity/Q29'), ('cname', 'Spain')]
# 20

# %%
#Restricting Countries to Europe only
queryString = """
SELECT DISTINCT (COUNT(?poet) AS ?NumOfPoets) ?coc ?cname
WHERE {
   # bind something
   # ?poet ?obj wd:Q37068;
   wdt:P106 wd:Q49757;
    wdt:P27 ?coc.
    # ?coc wdt:P30 wd:Q46.
    #?poet sc:name ?poname.
    # ?coc sc:name ?cname.
}
GROUP BY ?coc ?cname
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('NumOfPoets', '1'), ('coc', 'http://www.wikidata.org/entity/Q156199'), ('cname', 'Electorate of Saxony')]
# [('NumOfPoets', '4'), ('coc', 'http://www.wikidata.org/entity/Q218'), ('cname', 'Romania')]
# [('NumOfPoets', '1'), ('coc', 'http://www.wikidata.org/entity/Q222'), ('cname', 'Albania')]
# [('NumOfPoets', '1'), ('coc', 'http://www.wikidata.org/entity/Q28'), ('cname', 'Hungary')]
# [('NumOfPoets', '1'), ('coc', 'http://www.wikidata.org/entity/Q958291'), ('cname', 'United Principalities')]
# [('NumOfPoets', '1'), ('coc', 'http://www.wikidata.org/entity/Q12560'), ('cname', 'Ottoman Empire')]
# [('NumOfPoets', '9'), ('coc', 'http://www.wikidata.org/entity/Q183'), ('cname', 'Germany')]
# [('NumOfPoets', '7'), ('coc', 'http://www.wikidata.org/entity/Q174193'), ('cname', 'United Kingdom of Great Britain and Ireland')]
# [('NumOfPoets', '3'), ('coc', 'http://www.wikidata.org/entity/Q31'), ('cname', 'Belgium')]
# [('NumOfPoets', '1'), ('coc', 'http://www.wikidata.org/entity/Q403'), ('cname', 'Serbia')]
# [('NumOfPoets', '1'), ('coc', 'http://www.wikidata.org/entity/Q221457'), ('cname', 'Congress Poland')]
# [('NumOfPoets', '1'), ('coc', 'http://www.wikidata.org/entity/Q699923'), ('cname', 'Illyrian Provinces')]
# [('NumOfPoets', '1'), ('coc', 'http://www.wikidata.org/entity/Q172107'), ('cname', 'Polish–Lithuanian Commonwealth')]
# [('NumOfPoets', '48'), ('coc', 'http://www.wikidata.org/entity/Q29'), ('cname', 'Spain')]
# [('NumOfPoets', '1'), ('coc', 'http://www.wikidata.org/entity/Q80702'), ('cname', 'Spanish Empire')]
# [('NumOfPoets', '16'), ('coc', 'http://www.wikidata.org/entity/Q142'), ('cname', 'France')]
# [('NumOfPoets', '8'), ('coc', 'http://www.wikidata.org/entity/Q161885'), ('cname', 'Great Britain')]
# [('NumOfPoets', '1'), ('coc', 'http://www.wikidata.org/entity/Q10957559'), ('cname', 'Principality of Moldavia')]
# [('NumOfPoets', '1'), ('coc', 'http://www.wikidata.org/entity/Q227'), ('cname', 'Azerbaijan')]
# [('NumOfPoets', '4'), ('coc', 'http://www.wikidata.org/entity/Q45'), ('cname', 'Portugal')]
# 20

# %% [markdown]
# Final query for this task

# %%
# write your final query
queryString = """
SELECT DISTINCT (COUNT(?poet) AS ?NumOfPoets) ?coc ?cname
WHERE {
   # bind something
   # ?poet ?obj wd:Q37068;
   wdt:P106 wd:Q49757;
    wdt:P27 ?coc.
    # ?coc wdt:P30 wd:Q46.
    #?poet sc:name ?poname.
    # ?coc sc:name ?cname.
}
GROUP BY ?coc ?cname
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('NumOfPoets', '1'), ('coc', 'http://www.wikidata.org/entity/Q156199'), ('cname', 'Electorate of Saxony')]
# [('NumOfPoets', '4'), ('coc', 'http://www.wikidata.org/entity/Q218'), ('cname', 'Romania')]
# [('NumOfPoets', '1'), ('coc', 'http://www.wikidata.org/entity/Q222'), ('cname', 'Albania')]
# [('NumOfPoets', '1'), ('coc', 'http://www.wikidata.org/entity/Q28'), ('cname', 'Hungary')]
# [('NumOfPoets', '1'), ('coc', 'http://www.wikidata.org/entity/Q958291'), ('cname', 'United Principalities')]
# [('NumOfPoets', '1'), ('coc', 'http://www.wikidata.org/entity/Q12560'), ('cname', 'Ottoman Empire')]
# [('NumOfPoets', '9'), ('coc', 'http://www.wikidata.org/entity/Q183'), ('cname', 'Germany')]
# [('NumOfPoets', '7'), ('coc', 'http://www.wikidata.org/entity/Q174193'), ('cname', 'United Kingdom of Great Britain and Ireland')]
# [('NumOfPoets', '3'), ('coc', 'http://www.wikidata.org/entity/Q31'), ('cname', 'Belgium')]
# [('NumOfPoets', '1'), ('coc', 'http://www.wikidata.org/entity/Q403'), ('cname', 'Serbia')]
# [('NumOfPoets', '1'), ('coc', 'http://www.wikidata.org/entity/Q221457'), ('cname', 'Congress Poland')]
# [('NumOfPoets', '1'), ('coc', 'http://www.wikidata.org/entity/Q699923'), ('cname', 'Illyrian Provinces')]
# [('NumOfPoets', '1'), ('coc', 'http://www.wikidata.org/entity/Q172107'), ('cname', 'Polish–Lithuanian Commonwealth')]
# [('NumOfPoets', '48'), ('coc', 'http://www.wikidata.org/entity/Q29'), ('cname', 'Spain')]
# [('NumOfPoets', '1'), ('coc', 'http://www.wikidata.org/entity/Q80702'), ('cname', 'Spanish Empire')]
# [('NumOfPoets', '16'), ('coc', 'http://www.wikidata.org/entity/Q142'), ('cname', 'France')]
# [('NumOfPoets', '8'), ('coc', 'http://www.wikidata.org/entity/Q161885'), ('cname', 'Great Britain')]
# [('NumOfPoets', '1'), ('coc', 'http://www.wikidata.org/entity/Q10957559'), ('cname', 'Principality of Moldavia')]
# [('NumOfPoets', '1'), ('coc', 'http://www.wikidata.org/entity/Q227'), ('cname', 'Azerbaijan')]
# [('NumOfPoets', '4'), ('coc', 'http://www.wikidata.org/entity/Q45'), ('cname', 'Portugal')]
# 20

# %% [markdown]
# ## Task 7
# Find the number of sculptures in the Louvre Museum belonging to Renaissance, Baroque, or Romanticism (return a number for each movement) (the result set must be a list of triples movement IRI, label and #sculptures).

# %%
# write your queries
# Exploring Louvre Museum BGP
queryString = """
SELECT DISTINCT ?oname ?name ?p ?obj
WHERE {
   # bind something
   wd:Q19675 ?obj ?p.
   # get the label
   # ?p sc:name ?name.
   # ?obj sc:name ?oname.
   FILTER(REGEX(?name,"Sculptures"^^xsd:string))
}
LIMIT 200
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('oname', 'has part'), ('name', 'Department of Sculptures of the Louvre'), ('p', 'http://www.wikidata.org/entity/Q3044772'), ('obj', 'http://www.wikidata.org/prop/direct/P527')]
# 1

# %%
# write your queries
# Exploring Department of Sculptures of the Louvre
queryString = """
SELECT DISTINCT ?p ?name ?obj ?oname
WHERE {
   # bind something
    # ?obj ?p wd:Q3044772.
   # get the label
   # ?p sc:name ?name.
   # ?obj sc:name ?oname.
}
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P301'), ('name', "category's main topic"), ('obj', 'http://www.wikidata.org/entity/Q8723838'), ('oname', 'Category:Sculptures of the Louvre')]
# [('p', 'http://www.wikidata.org/prop/direct/P195'), ('name', 'collection'), ('obj', 'http://www.wikidata.org/entity/Q17451496'), ('oname', 'Nymph with a Scorpion')]
# [('p', 'http://www.wikidata.org/prop/direct/P195'), ('name', 'collection'), ('obj', 'http://www.wikidata.org/entity/Q106350990'), ('oname', 'Farnese Flora')]
# [('p', 'http://www.wikidata.org/prop/direct/P195'), ('name', 'collection'), ('obj', 'http://www.wikidata.org/entity/Q18147625'), ('oname', 'Farnese Flora')]
# [('p', 'http://www.wikidata.org/prop/direct/P195'), ('name', 'collection'), ('obj', 'http://www.wikidata.org/entity/Q18147637'), ('oname', 'Theseus Fighting the Minotaur')]
# [('p', 'http://www.wikidata.org/prop/direct/P195'), ('name', 'collection'), ('obj', 'http://www.wikidata.org/entity/Q18147662'), ('oname', 'Tiber')]
# [('p', 'http://www.wikidata.org/prop/direct/P195'), ('name', 'collection'), ('obj', 'http://www.wikidata.org/entity/Q18147663'), ('oname', 'Nile')]
# [('p', 'http://www.wikidata.org/prop/direct/P466'), ('name', 'occupant'), ('obj', 'http://www.wikidata.org/entity/Q19301715'), ('oname', 'Sculptures italiennes et espagnoles, salle 160, Entresol, Denon')]
# [('p', 'http://www.wikidata.org/prop/direct/P466'), ('name', 'occupant'), ('obj', 'http://www.wikidata.org/entity/Q19338575'), ('oname', 'Room 206')]
# [('p', 'http://www.wikidata.org/prop/direct/P466'), ('name', 'occupant'), ('obj', 'http://www.wikidata.org/entity/Q19338577'), ('oname', 'Room 207')]
# [('p', 'http://www.wikidata.org/prop/direct/P466'), ('name', 'occupant'), ('obj', 'http://www.wikidata.org/entity/Q19338711'), ('oname', 'Room 211')]
# [('p', 'http://www.wikidata.org/prop/direct/P466'), ('name', 'occupant'), ('obj', 'http://www.wikidata.org/entity/Q19338719'), ('oname', 'Room 216')]
# [('p', 'http://www.wikidata.org/prop/direct/P195'), ('name', 'collection'), ('obj', 'http://www.wikidata.org/entity/Q19347123'), ('oname', 'Bacchant')]
# [('p', 'http://www.wikidata.org/prop/direct/P195'), ('name', 'collection'), ('obj', 'http://www.wikidata.org/entity/Q22946196'), ('oname', 'Amour de Saly')]
# [('p', 'http://www.wikidata.org/prop/direct/P195'), ('name', 'collection'), ('obj', 'http://www.wikidata.org/entity/Q2962628'), ('oname', 'Sculpted Andirons')]
# [('p', 'http://www.wikidata.org/prop/direct/P195'), ('name', 'collection'), ('obj', 'http://www.wikidata.org/entity/Q19120283'), ('oname', 'Hurt Niobid')]
# [('p', 'http://www.wikidata.org/prop/direct/P195'), ('name', 'collection'), ('obj', 'http://www.wikidata.org/entity/Q19120310'), ('oname', 'Satyre et bacchante by James Pradier')]
# [('p', 'http://www.wikidata.org/prop/direct/P466'), ('name', 'occupant'), ('obj', 'http://www.wikidata.org/entity/Q19280253'), ('oname', 'French sculptures, room 29')]
# [('p', 'http://www.wikidata.org/prop/direct/P466'), ('name', 'occupant'), ('obj', 'http://www.wikidata.org/entity/Q19341368'), ('oname', 'Room 221')]
# [('p', 'http://www.wikidata.org/prop/direct/P195'), ('name', 'collection'), ('obj', 'http://www.wikidata.org/entity/Q19753091'), ('oname', 'Diana')]
# 20

# %%
#Getting Specific Collection for exploring
queryString = """
SELECT DISTINCT ?p ?name ?obj ?oname
WHERE {
   # bind something
    wd:Q19753091 ?obj ?p.
   # get the label
   # ?p sc:name ?name.
   # ?obj sc:name ?oname.
}
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/entity/Q40446'), ('name', 'nude'), ('obj', 'http://www.wikidata.org/prop/direct/P136'), ('oname', 'genre')]
# [('p', 'http://www.wikidata.org/entity/Q318741'), ('name', 'Jean-Antoine Houdon'), ('obj', 'http://www.wikidata.org/prop/direct/P170'), ('oname', 'creator')]
# [('p', 'http://www.wikidata.org/entity/Q10791'), ('name', 'nudity'), ('obj', 'http://www.wikidata.org/prop/direct/P180'), ('oname', 'depicts')]
# [('p', 'http://www.wikidata.org/entity/Q132543'), ('name', 'Diana'), ('obj', 'http://www.wikidata.org/prop/direct/P180'), ('oname', 'depicts')]
# [('p', 'http://www.wikidata.org/entity/Q46311'), ('name', 'bow'), ('obj', 'http://www.wikidata.org/prop/direct/P180'), ('oname', 'depicts')]
# [('p', 'http://www.wikidata.org/entity/Q45922'), ('name', 'arrow'), ('obj', 'http://www.wikidata.org/prop/direct/P180'), ('oname', 'depicts')]
# [('p', 'http://www.wikidata.org/entity/Q327496'), ('name', 'hairstyle'), ('obj', 'http://www.wikidata.org/prop/direct/P180'), ('oname', 'depicts')]
# [('p', 'http://www.wikidata.org/entity/Q34095'), ('name', 'bronze'), ('obj', 'http://www.wikidata.org/prop/direct/P186'), ('oname', 'made from material')]
# [('p', 'http://www.wikidata.org/entity/Q3044772'), ('name', 'Department of Sculptures of the Louvre'), ('obj', 'http://www.wikidata.org/prop/direct/P195'), ('oname', 'collection')]
# [('p', 'http://www.wikidata.org/entity/Q19280253'), ('name', 'French sculptures, room 29'), ('obj', 'http://www.wikidata.org/prop/direct/P276'), ('oname', 'location')]
# [('p', 'http://www.wikidata.org/entity/Q860861'), ('name', 'sculpture'), ('obj', 'http://www.wikidata.org/prop/direct/P31'), ('oname', 'instance of')]
# 11

# %%
# write your queries
# Exploring sculpture BGP
#[('p', 'http://www.wikidata.org/entity/Q860861'), ('name', 'sculpture')
queryString = """
SELECT DISTINCT ?oname ?name ?p ?obj
WHERE {
   # bind something
    wd:Q860861 ?obj ?p .
   # get the label
   # ?p sc:name ?name.
   # ?obj sc:name ?oname.
}
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('oname', 'field of work'), ('name', 'art of sculpture'), ('p', 'http://www.wikidata.org/entity/Q11634'), ('obj', 'http://www.wikidata.org/prop/direct/P101')]
# [('oname', 'described by source'), ('name', 'Metropolitan Museum of Art Tagging Vocabulary'), ('p', 'http://www.wikidata.org/entity/Q106727050'), ('obj', 'http://www.wikidata.org/prop/direct/P1343')]
# [('oname', 'different from'), ('name', 'art of sculpture'), ('p', 'http://www.wikidata.org/entity/Q11634'), ('obj', 'http://www.wikidata.org/prop/direct/P1889')]
# [('oname', 'properties for this type'), ('name', 'Vanderkrogt.net Statues ID'), ('p', 'http://www.wikidata.org/entity/P3711'), ('obj', 'http://www.wikidata.org/prop/direct/P1963')]
# [('oname', 'fabrication method'), ('name', 'sculpture technique'), ('p', 'http://www.wikidata.org/entity/Q21711025'), ('obj', 'http://www.wikidata.org/prop/direct/P2079')]
# [('oname', 'subclass of'), ('name', 'visual artwork'), ('p', 'http://www.wikidata.org/entity/Q4502142'), ('obj', 'http://www.wikidata.org/prop/direct/P279')]
# [('oname', 'subclass of'), ('name', 'physical object'), ('p', 'http://www.wikidata.org/entity/Q223557'), ('obj', 'http://www.wikidata.org/prop/direct/P279')]
# [('oname', 'subclass of'), ('name', 'small monument'), ('p', 'http://www.wikidata.org/entity/Q1746392'), ('obj', 'http://www.wikidata.org/prop/direct/P279')]
# [('oname', 'Wikimedia outline'), ('name', 'outline of sculpture'), ('p', 'http://www.wikidata.org/entity/Q7112723'), ('obj', 'http://www.wikidata.org/prop/direct/P5125')]
# [('oname', "topic's main category"), ('name', 'Category:Sculptures'), ('p', 'http://www.wikidata.org/entity/Q6928659'), ('obj', 'http://www.wikidata.org/prop/direct/P910')]
# 10

# %% [markdown]
# Final query for this task

# %%
#[('p', 'http://www.wikidata.org/entity/Q37068'), ('name', 'Romanticism')]
#[('p', 'http://www.wikidata.org/entity/Q37853'), ('name', 'Baroque')]
#[('p', 'http://www.wikidata.org/entity/Q4692'), ('name', 'Renaissance')]
queryString = """
SELECT DISTINCT ?oname ?name ?p ?obj
WHERE {
   # bind something
    wd:Q37068 ?obj ?p .
   # get the label
   # ?p sc:name ?name.
   # ?obj sc:name ?oname.
   #FILTER(REGEX(?name,"sculpture"^^xsd:string))
}
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('oname', 'described by source'), ('name', 'The Nuttall Encyclopædia'), ('p', 'http://www.wikidata.org/entity/Q3181656'), ('obj', 'http://www.wikidata.org/prop/direct/P1343')]
# [('oname', 'described by source'), ('name', "Riemann's Music Dictionary (1901–1904)"), ('p', 'http://www.wikidata.org/entity/Q27680201'), ('obj', 'http://www.wikidata.org/prop/direct/P1343')]
# [('oname', 'follows'), ('name', 'neoclassicism'), ('p', 'http://www.wikidata.org/entity/Q14378'), ('obj', 'http://www.wikidata.org/prop/direct/P155')]
# [('oname', 'follows'), ('name', 'Pre-romanticism'), ('p', 'http://www.wikidata.org/entity/Q2614483'), ('obj', 'http://www.wikidata.org/prop/direct/P155')]
# [('oname', 'followed by'), ('name', 'Post-romanticism'), ('p', 'http://www.wikidata.org/entity/Q1125039'), ('obj', 'http://www.wikidata.org/prop/direct/P156')]
# [('oname', 'instance of'), ('name', 'literary movement'), ('p', 'http://www.wikidata.org/entity/Q3326717'), ('obj', 'http://www.wikidata.org/prop/direct/P31')]
# [('oname', 'instance of'), ('name', 'architectural style'), ('p', 'http://www.wikidata.org/entity/Q32880'), ('obj', 'http://www.wikidata.org/prop/direct/P31')]
# [('oname', 'instance of'), ('name', 'art style'), ('p', 'http://www.wikidata.org/entity/Q1792644'), ('obj', 'http://www.wikidata.org/prop/direct/P31')]
# [('oname', 'instance of'), ('name', 'art movement'), ('p', 'http://www.wikidata.org/entity/Q968159'), ('obj', 'http://www.wikidata.org/prop/direct/P31')]
# [('oname', 'instance of'), ('name', 'cultural movement'), ('p', 'http://www.wikidata.org/entity/Q2198855'), ('obj', 'http://www.wikidata.org/prop/direct/P31')]
# [('oname', 'has part'), ('name', 'Romantic music'), ('p', 'http://www.wikidata.org/entity/Q207591'), ('obj', 'http://www.wikidata.org/prop/direct/P527')]
# [('oname', 'has part'), ('name', 'Romantic painting'), ('p', 'http://www.wikidata.org/entity/Q3088366'), ('obj', 'http://www.wikidata.org/prop/direct/P527')]
# [('oname', 'has part'), ('name', 'romantic drama'), ('p', 'http://www.wikidata.org/entity/Q3038946'), ('obj', 'http://www.wikidata.org/prop/direct/P527')]
# [('oname', 'has part'), ('name', 'Romantic philosophy'), ('p', 'http://www.wikidata.org/entity/Q12775412'), ('obj', 'http://www.wikidata.org/prop/direct/P527')]
# [('oname', 'has part'), ('name', 'romantic literature'), ('p', 'http://www.wikidata.org/entity/Q5977111'), ('obj', 'http://www.wikidata.org/prop/direct/P527')]
# [('oname', "topic's main category"), ('name', 'Category:Romanticism'), ('p', 'http://www.wikidata.org/entity/Q7154269'), ('obj', 'http://www.wikidata.org/prop/direct/P910')]
# 16

# %%
#[('p', 'http://www.wikidata.org/entity/Q37068'), ('name', 'Romanticism')]
#[('p', 'http://www.wikidata.org/entity/Q37853'), ('name', 'Baroque')]
#[('p', 'http://www.wikidata.org/entity/Q4692'), ('name', 'Renaissance')]
#Exploring art style
queryString = """
SELECT DISTINCT ?oname ?name ?p ?obj
WHERE {
   # bind something
    wd:Q968159 ?obj ?p .
   # get the label
   # ?p sc:name ?name.
   # ?obj sc:name ?oname.
   #FILTER(REGEX(?name,"sculpture"^^xsd:string))
}
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('oname', "topic's main template"), ('name', 'Template:Infobox art movement'), ('p', 'http://www.wikidata.org/entity/Q14412130'), ('obj', 'http://www.wikidata.org/prop/direct/P1424')]
# [('oname', 'different from'), ('name', 'art group'), ('p', 'http://www.wikidata.org/entity/Q4502119'), ('obj', 'http://www.wikidata.org/prop/direct/P1889')]
# [('oname', 'has list'), ('name', 'list of art movements'), ('p', 'http://www.wikidata.org/entity/Q1293970'), ('obj', 'http://www.wikidata.org/prop/direct/P2354')]
# [('oname', 'subclass of'), ('name', 'art'), ('p', 'http://www.wikidata.org/entity/Q735'), ('obj', 'http://www.wikidata.org/prop/direct/P279')]
# [('oname', 'subclass of'), ('name', 'cultural movement'), ('p', 'http://www.wikidata.org/entity/Q2198855'), ('obj', 'http://www.wikidata.org/prop/direct/P279')]
# [('oname', "topic's main category"), ('name', 'Category:Art movements'), ('p', 'http://www.wikidata.org/entity/Q7458526'), ('obj', 'http://www.wikidata.org/prop/direct/P910')]
# 6

# %%
#[('p', 'http://www.wikidata.org/entity/Q37068'), ('name', 'Romanticism')]
#[('p', 'http://www.wikidata.org/entity/Q37853'), ('name', 'Baroque')]
#[('p', 'http://www.wikidata.org/entity/Q4692'), ('name', 'Renaissance')]
#Exploring art style
#Exploring art group
queryString = """
SELECT DISTINCT ?oname ?name ?p ?obj
WHERE {
   # bind something
    wd:Q4502119 ?obj ?p .
   # get the label
   # ?p sc:name ?name.
   # ?obj sc:name ?oname.
   #FILTER(REGEX(?name,"sculpture"^^xsd:string))
}
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('oname', 'field of work'), ('name', 'art'), ('p', 'http://www.wikidata.org/entity/Q735'), ('obj', 'http://www.wikidata.org/prop/direct/P101')]
# [('oname', 'different from'), ('name', 'art society'), ('p', 'http://www.wikidata.org/entity/Q12160242'), ('obj', 'http://www.wikidata.org/prop/direct/P1889')]
# [('oname', 'different from'), ('name', 'artist collective'), ('p', 'http://www.wikidata.org/entity/Q1400264'), ('obj', 'http://www.wikidata.org/prop/direct/P1889')]
# [('oname', 'different from'), ('name', 'art genre'), ('p', 'http://www.wikidata.org/entity/Q1792379'), ('obj', 'http://www.wikidata.org/prop/direct/P1889')]
# [('oname', 'different from'), ('name', 'art movement'), ('p', 'http://www.wikidata.org/entity/Q968159'), ('obj', 'http://www.wikidata.org/prop/direct/P1889')]
# [('oname', 'subclass of'), ('name', 'group of humans'), ('p', 'http://www.wikidata.org/entity/Q16334295'), ('obj', 'http://www.wikidata.org/prop/direct/P279')]
# [('oname', 'subclass of'), ('name', 'voluntary organization'), ('p', 'http://www.wikidata.org/entity/Q48204'), ('obj', 'http://www.wikidata.org/prop/direct/P279')]
# [('oname', 'instance of'), ('name', 'organization'), ('p', 'http://www.wikidata.org/entity/Q43229'), ('obj', 'http://www.wikidata.org/prop/direct/P31')]
# [('oname', 'model item'), ('name', 'Les XX'), ('p', 'http://www.wikidata.org/entity/Q463283'), ('obj', 'http://www.wikidata.org/prop/direct/P5869')]
# [('oname', "topic's main category"), ('name', 'Category:Artist groups and collectives'), ('p', 'http://www.wikidata.org/entity/Q6417957'), ('obj', 'http://www.wikidata.org/prop/direct/P910')]
# 10

# %%
#[('p', 'http://www.wikidata.org/entity/Q37068'), ('name', 'Romanticism')]
#[('p', 'http://www.wikidata.org/entity/Q37853'), ('name', 'Baroque')]
#[('p', 'http://www.wikidata.org/entity/Q4692'), ('name', 'Renaissance')]
#Exploring art style - art group - art genre
queryString = """
SELECT DISTINCT ?oname ?name ?p ?obj
WHERE {
   # bind something
     # ?obj ?p wd:Q1792379.
   # get the label
   # ?p sc:name ?name.
   # ?obj sc:name ?oname.
   FILTER(REGEX(?oname,"visual"^^xsd:string))
}
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('oname', 'visual art'), ('name', 'instance of'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('obj', 'http://www.wikidata.org/entity/Q36649')]
# 1

# %%
#[('p', 'http://www.wikidata.org/entity/Q37068'), ('name', 'Romanticism')]
#[('p', 'http://www.wikidata.org/entity/Q37853'), ('name', 'Baroque')]
#[('p', 'http://www.wikidata.org/entity/Q4692'), ('name', 'Renaissance')]
#Exploring art style - art group - art genre - visual art
queryString = """
SELECT DISTINCT ?oname ?name ?p ?obj
WHERE {
   # bind something
     # ?obj ?p wd:Q36649.
   # get the label
   # ?p sc:name ?name.
   # ?obj sc:name ?oname.
   FILTER(REGEX(?oname,"visual"^^xsd:string))
}
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('oname', 'Pori city board of visual arts'), ('name', 'field of work'), ('p', 'http://www.wikidata.org/prop/direct/P101'), ('obj', 'http://www.wikidata.org/entity/Q21607642')]
# [('oname', 'visual artist'), ('name', 'product or material produced'), ('p', 'http://www.wikidata.org/prop/direct/P1056'), ('obj', 'http://www.wikidata.org/entity/Q3391743')]
# [('oname', 'visual art of the United States'), ('name', 'facet of'), ('p', 'http://www.wikidata.org/prop/direct/P1269'), ('obj', 'http://www.wikidata.org/entity/Q2311158')]
# [('oname', 'Armenian visual arts'), ('name', 'facet of'), ('p', 'http://www.wikidata.org/prop/direct/P1269'), ('obj', 'http://www.wikidata.org/entity/Q4198730')]
# [('oname', 'visual artwork'), ('name', 'different from'), ('p', 'http://www.wikidata.org/prop/direct/P1889'), ('obj', 'http://www.wikidata.org/entity/Q4502142')]
# [('oname', 'visual music'), ('name', 'subclass of'), ('p', 'http://www.wikidata.org/prop/direct/P279'), ('obj', 'http://www.wikidata.org/entity/Q7936612')]
# [('oname', 'visual art of the 2nd half of 20th-century'), ('name', 'subclass of'), ('p', 'http://www.wikidata.org/prop/direct/P279'), ('obj', 'http://www.wikidata.org/entity/Q11998967')]
# [('oname', 'visual artist'), ('name', 'field of this occupation'), ('p', 'http://www.wikidata.org/prop/direct/P425'), ('obj', 'http://www.wikidata.org/entity/Q3391743')]
# [('oname', 'Brain networks for visual creativity: a functional connectivity study of planning a visual artwork.'), ('name', 'main subject'), ('p', 'http://www.wikidata.org/prop/direct/P921'), ('obj', 'http://www.wikidata.org/entity/Q37518887')]
# [('oname', 'Image and Narrative: online magazine of the visual narrative'), ('name', 'main subject'), ('p', 'http://www.wikidata.org/prop/direct/P921'), ('obj', 'http://www.wikidata.org/entity/Q15756017')]
# [('oname', 'The sculpted word : Keats, ekphrasis, and the visual arts'), ('name', 'main subject'), ('p', 'http://www.wikidata.org/prop/direct/P921'), ('obj', 'http://www.wikidata.org/entity/Q101161141')]
# [('oname', 'Allegory of the visual arts and music'), ('name', 'main subject'), ('p', 'http://www.wikidata.org/prop/direct/P921'), ('obj', 'http://www.wikidata.org/entity/Q100926444')]
# [('oname', 'Rebeca: Revista Brasileira de Estudos de Cinema e Audiovisual'), ('name', 'main subject'), ('p', 'http://www.wikidata.org/prop/direct/P921'), ('obj', 'http://www.wikidata.org/entity/Q50816837')]
# 13

# %%
#[('p', 'http://www.wikidata.org/entity/Q37068'), ('name', 'Romanticism')]
#[('p', 'http://www.wikidata.org/entity/Q37853'), ('name', 'Baroque')]
#[('p', 'http://www.wikidata.org/entity/Q4692'), ('name', 'Renaissance')]
#Exploring art style - art group - art genre - visual art - visual artwork
queryString = """
SELECT DISTINCT ?oname ?name ?p ?obj
WHERE {
   # bind something
      # ?obj ?p wd:Q4502142.
   # get the label
   # ?p sc:name ?name.
   # ?obj sc:name ?oname.
   FILTER(REGEX(?oname,"sculpture"^^xsd:string))
}
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('oname', 'sculpture'), ('name', 'subclass of'), ('p', 'http://www.wikidata.org/prop/direct/P279'), ('obj', 'http://www.wikidata.org/entity/Q860861')]
# [('oname', 'Model and Surrealist Sculpture (Modele et sculpture surrealiste)'), ('name', 'instance of'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('obj', 'http://www.wikidata.org/entity/Q91941050')]
# [('oname', 'Political Prisoner (maquette for sculpture)'), ('name', 'instance of'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('obj', 'http://www.wikidata.org/entity/Q91931714')]
# 3

# %%
# write your final query

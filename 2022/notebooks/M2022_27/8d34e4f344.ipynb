# %% [markdown]
# # General instructions
#
# The goal of the project is to materialize a set of **exploratory workloads** over a real-world, large-scale,  open-domain KG: [WikiData](https://www.wikidata.org/wiki/Wikidata:Main_Page)
#
# An exploratory workload  is composed by a set of queries, where each query is related to the information obtained previously.
#
# An exploratory workload starts with a usually vague, open ended question, and does not assume the person issuing the workload has a clear understanding of the data contained in the target database or its structure.
#
# Remeber that:
#
# 1. All the queries must run in the python notebook
# 2. You can use classes and properties only if you find them via a SPARQL query that must be present in the notebook
# 3. You do not delete useless queries. Keep everything that is synthatically valid
#
# ```
# ?p <http://schema.org/name> ?name .
# ```
#
#     is the BGP returning a human-readable name of a property or a class in Wikidata.

# %%
## SETUP used later

from SPARQLWrapper import SPARQLWrapper, JSON


prefixString = """
##-8d34e4f344-##
PREFIX wd: <http://www.wikidata.org/entity/> 
PREFIX wdt: <http://www.wikidata.org/prop/direct/> 
PREFIX sc: <http://schema.org/>
"""

# select and construct queries
def run_query(queryString,verbose = True):
    to_run = prefixString + "\n" + queryString

    sparql = SPARQLWrapper("http://a256-gc1-03.srv.aau.dk:5820/sparql")
    sparql.setTimeout(300)
    sparql.setReturnFormat(JSON)
    sparql.setQuery(to_run)

    try :
        results = sparql.query()
        json_results = results.convert()
        if len(json_results['results']['bindings'])==0:
            print("Empty")
            return []
        array = []
        for bindings in json_results['results']['bindings']:
            app =  [ (var, value['value'])  for var, value in bindings.items() ] 
            if verbose:
                print( app)
            array.append(app)
        if verbose:
            print(len(array))
        return array

    except Exception as e :
        print("The operation failed", e)
    
# ASk queries
def run_ask_query(queryString):
    to_run = prefixString + "\n" + queryString

    sparql = SPARQLWrapper("http://a256-gc1-03.srv.aau.dk:5820/sparql")
    sparql.setTimeout(300)
    sparql.setReturnFormat(JSON)
    sparql.setQuery(to_run)

    try :
        return sparql.query().convert()

    except Exception as e :
        print("The operation failed", e)

# %% [markdown]
# # History Workflow Series ("Euro explorative search")
#
# Consider the following exploratory information need:
#
# > investigate the Euro currency, which are the countries that currently use the Euro and which were their currencies before the Euro. Take a look also to other currencies and find which are the most used.

# %% [markdown]
# ## Useful URIs for the current workflow
# The following are given:
#
# | IRI           | Description   | Role      |
# | -----------   | -----------   |-----------|
# | `wdt:P1647`   | subproperty   | predicate |
# | `wdt:P31`     | instance of   | predicate |
# | `wdt:P106`    | occupation    | predicate |
# | `wdt:P279`    | subclass      | predicate |
# | `wdt:P27`     | nationality   | predicate |
# | `wd:Q5`| Human       | node |
# | `wd:Q38`| Italy   | node |

# %% [markdown]
# Also consider
#
# ```
# wd:Q38 ?p ?obj .
# ```
#
# is the BGP to retrieve all **properties of Italy**
#
# Please consider that when you return a resource, you should return the IRI and the label of the resource. In particular, when the task require you to identify a BGP the result set must always be a list of couples IRI - label.
#
#
#
# The workload should:
#
#
# 1. Identify the BGP for currency
#
# 2. Return the countries which currently use Euro
#
# 3. Return the countries belonging to the European Union, with a currency different from the Euro (return also their currency).
#
# 4. For each country that now uses Euro return which was the currencies used before
#
# 5. Return all types of dollar in the world (US Dollar, Australian Dollar, ecc...)
#
# 6. Return the currencies used in at least 2 different countries (return also the number of countries using each currency).
#
# 7. Consider the currencies obtained in task 6, for each currency return the number of people using that currency (hint: consider the maximum popolation available for each country).

# %% [markdown]
# ## Task 1
# Identify the BGP for currency

# %%
# return all properties for Italy
queryString = """
SELECT DISTINCT ?p ?name
WHERE {
   # bind something
   wd:Q38 ?p ?obj .
   # get the label
   # ?p sc:name ?name.
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P1005'), ('name', 'Portuguese National Library ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1036'), ('name', 'Dewey Decimal Classification')]
# [('p', 'http://www.wikidata.org/prop/direct/P1081'), ('name', 'Human Development Index')]
# [('p', 'http://www.wikidata.org/prop/direct/P1082'), ('name', 'population')]
# [('p', 'http://www.wikidata.org/prop/direct/P1120'), ('name', 'number of deaths')]
# [('p', 'http://www.wikidata.org/prop/direct/P1151'), ('name', "topic's main Wikimedia portal")]
# [('p', 'http://www.wikidata.org/prop/direct/P1198'), ('name', 'unemployment rate')]
# [('p', 'http://www.wikidata.org/prop/direct/P122'), ('name', 'basic form of government')]
# [('p', 'http://www.wikidata.org/prop/direct/P1225'), ('name', 'U.S. National Archives Identifier')]
# [('p', 'http://www.wikidata.org/prop/direct/P1245'), ('name', 'OmegaWiki Defined Meaning')]
# [('p', 'http://www.wikidata.org/prop/direct/P1296'), ('name', 'Gran Enciclopèdia Catalana ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1313'), ('name', 'office held by head of government')]
# [('p', 'http://www.wikidata.org/prop/direct/P1343'), ('name', 'described by source')]
# [('p', 'http://www.wikidata.org/prop/direct/P1365'), ('name', 'replaces')]
# [('p', 'http://www.wikidata.org/prop/direct/P1417'), ('name', 'Encyclopædia Britannica Online ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1419'), ('name', 'shape')]
# [('p', 'http://www.wikidata.org/prop/direct/P1438'), ('name', 'Jewish Encyclopedia ID (Russian)')]
# [('p', 'http://www.wikidata.org/prop/direct/P1451'), ('name', 'motto text')]
# [('p', 'http://www.wikidata.org/prop/direct/P1464'), ('name', 'category for people born here')]
# [('p', 'http://www.wikidata.org/prop/direct/P1465'), ('name', 'category for people who died here')]
# [('p', 'http://www.wikidata.org/prop/direct/P150'), ('name', 'contains administrative territorial entity')]
# [('p', 'http://www.wikidata.org/prop/direct/P1549'), ('name', 'demonym')]
# [('p', 'http://www.wikidata.org/prop/direct/P155'), ('name', 'follows')]
# [('p', 'http://www.wikidata.org/prop/direct/P1552'), ('name', 'has quality')]
# [('p', 'http://www.wikidata.org/prop/direct/P1566'), ('name', 'GeoNames ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1589'), ('name', 'lowest point')]
# [('p', 'http://www.wikidata.org/prop/direct/P1617'), ('name', 'BBC Things ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1622'), ('name', 'driving side')]
# [('p', 'http://www.wikidata.org/prop/direct/P163'), ('name', 'flag')]
# [('p', 'http://www.wikidata.org/prop/direct/P1667'), ('name', 'Getty Thesaurus of Geographic Names ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P17'), ('name', 'country')]
# [('p', 'http://www.wikidata.org/prop/direct/P1740'), ('name', 'category for films shot at this location')]
# [('p', 'http://www.wikidata.org/prop/direct/P1791'), ('name', 'category of people buried here')]
# [('p', 'http://www.wikidata.org/prop/direct/P1792'), ('name', 'category of associated people')]
# [('p', 'http://www.wikidata.org/prop/direct/P1842'), ('name', 'Global Anabaptist Mennonite Encyclopedia Online ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1906'), ('name', 'office held by head of state')]
# [('p', 'http://www.wikidata.org/prop/direct/P194'), ('name', 'legislative body')]
# [('p', 'http://www.wikidata.org/prop/direct/P2004'), ('name', 'NALT ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2046'), ('name', 'area')]
# [('p', 'http://www.wikidata.org/prop/direct/P206'), ('name', 'located in or next to body of water')]
# [('p', 'http://www.wikidata.org/prop/direct/P208'), ('name', 'executive body')]
# [('p', 'http://www.wikidata.org/prop/direct/P209'), ('name', 'highest judicial authority')]
# [('p', 'http://www.wikidata.org/prop/direct/P213'), ('name', 'ISNI')]
# [('p', 'http://www.wikidata.org/prop/direct/P214'), ('name', 'VIAF ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2163'), ('name', 'FAST ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2184'), ('name', 'history of topic')]
# [('p', 'http://www.wikidata.org/prop/direct/P2250'), ('name', 'life expectancy')]
# [('p', 'http://www.wikidata.org/prop/direct/P2258'), ('name', 'mobile country code')]
# [('p', 'http://www.wikidata.org/prop/direct/P227'), ('name', 'GND ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2347'), ('name', 'YSO ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P237'), ('name', 'coat of arms')]
# [('p', 'http://www.wikidata.org/prop/direct/P242'), ('name', 'locator map image')]
# [('p', 'http://www.wikidata.org/prop/direct/P244'), ('name', 'Library of Congress authority ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2573'), ('name', 'number of out-of-school children')]
# [('p', 'http://www.wikidata.org/prop/direct/P2581'), ('name', 'BabelNet ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2596'), ('name', 'culture')]
# [('p', 'http://www.wikidata.org/prop/direct/P2633'), ('name', 'geography of topic')]
# [('p', 'http://www.wikidata.org/prop/direct/P2852'), ('name', 'emergency telephone number')]
# [('p', 'http://www.wikidata.org/prop/direct/P2853'), ('name', 'electrical plug type')]
# [('p', 'http://www.wikidata.org/prop/direct/P2855'), ('name', 'VAT-rate')]
# [('p', 'http://www.wikidata.org/prop/direct/P2884'), ('name', 'mains voltage')]
# [('p', 'http://www.wikidata.org/prop/direct/P2924'), ('name', 'Great Russian Encyclopedia Online ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2936'), ('name', 'language used')]
# [('p', 'http://www.wikidata.org/prop/direct/P2950'), ('name', 'Nomisma ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2959'), ('name', 'permanent duplicated item')]
# [('p', 'http://www.wikidata.org/prop/direct/P297'), ('name', 'ISO 3166-1 alpha-2 code')]
# [('p', 'http://www.wikidata.org/prop/direct/P2979'), ('name', 'maritime identification digits')]
# [('p', 'http://www.wikidata.org/prop/direct/P298'), ('name', 'ISO 3166-1 alpha-3 code')]
# [('p', 'http://www.wikidata.org/prop/direct/P2981'), ('name', 'UIC alphabetical country code')]
# [('p', 'http://www.wikidata.org/prop/direct/P2982'), ('name', 'UIC numerical country code')]
# [('p', 'http://www.wikidata.org/prop/direct/P299'), ('name', 'ISO 3166-1 numeric code')]
# [('p', 'http://www.wikidata.org/prop/direct/P2997'), ('name', 'age of majority')]
# [('p', 'http://www.wikidata.org/prop/direct/P30'), ('name', 'continent')]
# [('p', 'http://www.wikidata.org/prop/direct/P3000'), ('name', 'marriageable age')]
# [('p', 'http://www.wikidata.org/prop/direct/P3024'), ('name', 'ITU letter code')]
# [('p', 'http://www.wikidata.org/prop/direct/P3067'), ('name', 'GS1 country code')]
# [('p', 'http://www.wikidata.org/prop/direct/P3068'), ('name', 'WIPO ST.3')]
# [('p', 'http://www.wikidata.org/prop/direct/P3097'), ('name', 'ISBN identifier group')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('name', 'instance of')]
# [('p', 'http://www.wikidata.org/prop/direct/P3106'), ('name', 'Guardian topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3175'), ('name', 'Statoids ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3219'), ('name', 'Encyclopædia Universalis ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3221'), ('name', 'New York Times topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3222'), ('name', 'NE.se ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3270'), ('name', 'compulsory education (minimum age)')]
# [('p', 'http://www.wikidata.org/prop/direct/P3271'), ('name', 'compulsory education (maximum age)')]
# [('p', 'http://www.wikidata.org/prop/direct/P3365'), ('name', 'Treccani ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3417'), ('name', 'Quora topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3422'), ('name', 'INSEE countries and foreign territories code')]
# [('p', 'http://www.wikidata.org/prop/direct/P3479'), ('name', 'Omni topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P349'), ('name', 'National Diet Library ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P35'), ('name', 'head of state')]
# [('p', 'http://www.wikidata.org/prop/direct/P3509'), ('name', 'Dagens Nyheter topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3529'), ('name', 'median income')]
# [('p', 'http://www.wikidata.org/prop/direct/P3553'), ('name', 'Zhihu topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P36'), ('name', 'capital')]
# [('p', 'http://www.wikidata.org/prop/direct/P361'), ('name', 'part of')]
# [('p', 'http://www.wikidata.org/prop/direct/P3612'), ('name', 'Le Monde diplomatique subject ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P37'), ('name', 'official language')]
# [('p', 'http://www.wikidata.org/prop/direct/P373'), ('name', 'Commons category')]
# 100

# %%
# return all properties for Italy
queryString = """
SELECT DISTINCT ?p ?name
WHERE {
   # bind something
   wd:Q38 ?p ?obj .
   # get the label
   # ?p sc:name ?name.
}
LIMIT 500
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P1005'), ('name', 'Portuguese National Library ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1036'), ('name', 'Dewey Decimal Classification')]
# [('p', 'http://www.wikidata.org/prop/direct/P1081'), ('name', 'Human Development Index')]
# [('p', 'http://www.wikidata.org/prop/direct/P1082'), ('name', 'population')]
# [('p', 'http://www.wikidata.org/prop/direct/P1120'), ('name', 'number of deaths')]
# [('p', 'http://www.wikidata.org/prop/direct/P1151'), ('name', "topic's main Wikimedia portal")]
# [('p', 'http://www.wikidata.org/prop/direct/P1198'), ('name', 'unemployment rate')]
# [('p', 'http://www.wikidata.org/prop/direct/P122'), ('name', 'basic form of government')]
# [('p', 'http://www.wikidata.org/prop/direct/P1225'), ('name', 'U.S. National Archives Identifier')]
# [('p', 'http://www.wikidata.org/prop/direct/P1245'), ('name', 'OmegaWiki Defined Meaning')]
# [('p', 'http://www.wikidata.org/prop/direct/P1296'), ('name', 'Gran Enciclopèdia Catalana ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1313'), ('name', 'office held by head of government')]
# [('p', 'http://www.wikidata.org/prop/direct/P1343'), ('name', 'described by source')]
# [('p', 'http://www.wikidata.org/prop/direct/P1365'), ('name', 'replaces')]
# [('p', 'http://www.wikidata.org/prop/direct/P1417'), ('name', 'Encyclopædia Britannica Online ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1419'), ('name', 'shape')]
# [('p', 'http://www.wikidata.org/prop/direct/P1438'), ('name', 'Jewish Encyclopedia ID (Russian)')]
# [('p', 'http://www.wikidata.org/prop/direct/P1451'), ('name', 'motto text')]
# [('p', 'http://www.wikidata.org/prop/direct/P1464'), ('name', 'category for people born here')]
# [('p', 'http://www.wikidata.org/prop/direct/P1465'), ('name', 'category for people who died here')]
# [('p', 'http://www.wikidata.org/prop/direct/P150'), ('name', 'contains administrative territorial entity')]
# [('p', 'http://www.wikidata.org/prop/direct/P1549'), ('name', 'demonym')]
# [('p', 'http://www.wikidata.org/prop/direct/P155'), ('name', 'follows')]
# [('p', 'http://www.wikidata.org/prop/direct/P1552'), ('name', 'has quality')]
# [('p', 'http://www.wikidata.org/prop/direct/P1566'), ('name', 'GeoNames ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1589'), ('name', 'lowest point')]
# [('p', 'http://www.wikidata.org/prop/direct/P1617'), ('name', 'BBC Things ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1622'), ('name', 'driving side')]
# [('p', 'http://www.wikidata.org/prop/direct/P163'), ('name', 'flag')]
# [('p', 'http://www.wikidata.org/prop/direct/P1667'), ('name', 'Getty Thesaurus of Geographic Names ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P17'), ('name', 'country')]
# [('p', 'http://www.wikidata.org/prop/direct/P1740'), ('name', 'category for films shot at this location')]
# [('p', 'http://www.wikidata.org/prop/direct/P1791'), ('name', 'category of people buried here')]
# [('p', 'http://www.wikidata.org/prop/direct/P1792'), ('name', 'category of associated people')]
# [('p', 'http://www.wikidata.org/prop/direct/P1842'), ('name', 'Global Anabaptist Mennonite Encyclopedia Online ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1906'), ('name', 'office held by head of state')]
# [('p', 'http://www.wikidata.org/prop/direct/P194'), ('name', 'legislative body')]
# [('p', 'http://www.wikidata.org/prop/direct/P2004'), ('name', 'NALT ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2046'), ('name', 'area')]
# [('p', 'http://www.wikidata.org/prop/direct/P206'), ('name', 'located in or next to body of water')]
# [('p', 'http://www.wikidata.org/prop/direct/P208'), ('name', 'executive body')]
# [('p', 'http://www.wikidata.org/prop/direct/P209'), ('name', 'highest judicial authority')]
# [('p', 'http://www.wikidata.org/prop/direct/P213'), ('name', 'ISNI')]
# [('p', 'http://www.wikidata.org/prop/direct/P214'), ('name', 'VIAF ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2163'), ('name', 'FAST ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2184'), ('name', 'history of topic')]
# [('p', 'http://www.wikidata.org/prop/direct/P2250'), ('name', 'life expectancy')]
# [('p', 'http://www.wikidata.org/prop/direct/P2258'), ('name', 'mobile country code')]
# [('p', 'http://www.wikidata.org/prop/direct/P227'), ('name', 'GND ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2347'), ('name', 'YSO ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P237'), ('name', 'coat of arms')]
# [('p', 'http://www.wikidata.org/prop/direct/P242'), ('name', 'locator map image')]
# [('p', 'http://www.wikidata.org/prop/direct/P244'), ('name', 'Library of Congress authority ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2573'), ('name', 'number of out-of-school children')]
# [('p', 'http://www.wikidata.org/prop/direct/P2581'), ('name', 'BabelNet ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2596'), ('name', 'culture')]
# [('p', 'http://www.wikidata.org/prop/direct/P2633'), ('name', 'geography of topic')]
# [('p', 'http://www.wikidata.org/prop/direct/P2852'), ('name', 'emergency telephone number')]
# [('p', 'http://www.wikidata.org/prop/direct/P2853'), ('name', 'electrical plug type')]
# [('p', 'http://www.wikidata.org/prop/direct/P2855'), ('name', 'VAT-rate')]
# [('p', 'http://www.wikidata.org/prop/direct/P2884'), ('name', 'mains voltage')]
# [('p', 'http://www.wikidata.org/prop/direct/P2924'), ('name', 'Great Russian Encyclopedia Online ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2936'), ('name', 'language used')]
# [('p', 'http://www.wikidata.org/prop/direct/P2950'), ('name', 'Nomisma ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2959'), ('name', 'permanent duplicated item')]
# [('p', 'http://www.wikidata.org/prop/direct/P297'), ('name', 'ISO 3166-1 alpha-2 code')]
# [('p', 'http://www.wikidata.org/prop/direct/P2979'), ('name', 'maritime identification digits')]
# [('p', 'http://www.wikidata.org/prop/direct/P298'), ('name', 'ISO 3166-1 alpha-3 code')]
# [('p', 'http://www.wikidata.org/prop/direct/P2981'), ('name', 'UIC alphabetical country code')]
# [('p', 'http://www.wikidata.org/prop/direct/P2982'), ('name', 'UIC numerical country code')]
# [('p', 'http://www.wikidata.org/prop/direct/P299'), ('name', 'ISO 3166-1 numeric code')]
# [('p', 'http://www.wikidata.org/prop/direct/P2997'), ('name', 'age of majority')]
# [('p', 'http://www.wikidata.org/prop/direct/P30'), ('name', 'continent')]
# [('p', 'http://www.wikidata.org/prop/direct/P3000'), ('name', 'marriageable age')]
# [('p', 'http://www.wikidata.org/prop/direct/P3024'), ('name', 'ITU letter code')]
# [('p', 'http://www.wikidata.org/prop/direct/P3067'), ('name', 'GS1 country code')]
# [('p', 'http://www.wikidata.org/prop/direct/P3068'), ('name', 'WIPO ST.3')]
# [('p', 'http://www.wikidata.org/prop/direct/P3097'), ('name', 'ISBN identifier group')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('name', 'instance of')]
# [('p', 'http://www.wikidata.org/prop/direct/P3106'), ('name', 'Guardian topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3175'), ('name', 'Statoids ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3219'), ('name', 'Encyclopædia Universalis ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3221'), ('name', 'New York Times topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3222'), ('name', 'NE.se ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3270'), ('name', 'compulsory education (minimum age)')]
# [('p', 'http://www.wikidata.org/prop/direct/P3271'), ('name', 'compulsory education (maximum age)')]
# [('p', 'http://www.wikidata.org/prop/direct/P3365'), ('name', 'Treccani ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3417'), ('name', 'Quora topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3422'), ('name', 'INSEE countries and foreign territories code')]
# [('p', 'http://www.wikidata.org/prop/direct/P3479'), ('name', 'Omni topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P349'), ('name', 'National Diet Library ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P35'), ('name', 'head of state')]
# [('p', 'http://www.wikidata.org/prop/direct/P3509'), ('name', 'Dagens Nyheter topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3529'), ('name', 'median income')]
# [('p', 'http://www.wikidata.org/prop/direct/P3553'), ('name', 'Zhihu topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P36'), ('name', 'capital')]
# [('p', 'http://www.wikidata.org/prop/direct/P361'), ('name', 'part of')]
# [('p', 'http://www.wikidata.org/prop/direct/P3612'), ('name', 'Le Monde diplomatique subject ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P37'), ('name', 'official language')]
# [('p', 'http://www.wikidata.org/prop/direct/P373'), ('name', 'Commons category')]
# [('p', 'http://www.wikidata.org/prop/direct/P3743'), ('name', 'ITU/ISO/IEC object identifier')]
# [('p', 'http://www.wikidata.org/prop/direct/P38'), ('name', 'currency')]
# [('p', 'http://www.wikidata.org/prop/direct/P3896'), ('name', 'geoshape')]
# [('p', 'http://www.wikidata.org/prop/direct/P3911'), ('name', 'STW Thesaurus for Economics ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3916'), ('name', 'UNESCO Thesaurus ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P395'), ('name', 'licence plate code')]
# [('p', 'http://www.wikidata.org/prop/direct/P3984'), ('name', 'subreddit')]
# [('p', 'http://www.wikidata.org/prop/direct/P3987'), ('name', 'SHARE Catalogue author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P402'), ('name', 'OpenStreetMap relation ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P4073'), ('name', 'Fandom wiki ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P41'), ('name', 'flag image')]
# [('p', 'http://www.wikidata.org/prop/direct/P417'), ('name', 'patron saint')]
# [('p', 'http://www.wikidata.org/prop/direct/P421'), ('name', 'located in time zone')]
# [('p', 'http://www.wikidata.org/prop/direct/P4342'), ('name', 'Store norske leksikon ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P4427'), ('name', 'GACS ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P443'), ('name', 'pronunciation audio')]
# [('p', 'http://www.wikidata.org/prop/direct/P4527'), ('name', 'UK Parliament thesaurus ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P4613'), ('name', 'Encyclopedia of Modern Ukraine ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P463'), ('name', 'member of')]
# [('p', 'http://www.wikidata.org/prop/direct/P4672'), ('name', 'EMLO location ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P47'), ('name', 'shares border with')]
# [('p', 'http://www.wikidata.org/prop/direct/P474'), ('name', 'country calling code')]
# [('p', 'http://www.wikidata.org/prop/direct/P4801'), ('name', 'LoC and MARC vocabularies ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P4841'), ('name', 'total fertility rate')]
# [('p', 'http://www.wikidata.org/prop/direct/P486'), ('name', 'MeSH descriptor ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P487'), ('name', 'Unicode character')]
# [('p', 'http://www.wikidata.org/prop/direct/P5002'), ('name', 'Orthodox Encyclopedia ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5008'), ('name', 'on focus list of Wikimedia project')]
# [('p', 'http://www.wikidata.org/prop/direct/P5019'), ('name', 'Brockhaus Enzyklopädie online ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5063'), ('name', 'Interlingual Index ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5125'), ('name', 'Wikimedia outline')]
# [('p', 'http://www.wikidata.org/prop/direct/P5180'), ('name', 'CIVICUS Monitor country entry')]
# [('p', 'http://www.wikidata.org/prop/direct/P5198'), ('name', 'ASC Leiden Thesaurus ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5247'), ('name', 'Giant Bomb ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5250'), ('name', 'IAB code')]
# [('p', 'http://www.wikidata.org/prop/direct/P530'), ('name', 'diplomatic relation')]
# [('p', 'http://www.wikidata.org/prop/direct/P5400'), ('name', 'GeoNLP ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5437'), ('name', 'EuroVoc ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5456'), ('name', 'TasteAtlas ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5573'), ('name', 'archINFORM location ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5658'), ('name', 'railway traffic side')]
# [('p', 'http://www.wikidata.org/prop/direct/P5698'), ('name', 'Invasive Species Compendium Datasheet ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P571'), ('name', 'inception')]
# [('p', 'http://www.wikidata.org/prop/direct/P5739'), ('name', 'Pontificia Università della Santa Croce ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5843'), ('name', 'Gynopedia ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5905'), ('name', 'Comic Vine ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6'), ('name', 'head of government')]
# [('p', 'http://www.wikidata.org/prop/direct/P605'), ('name', 'NUTS code')]
# [('p', 'http://www.wikidata.org/prop/direct/P610'), ('name', 'highest point')]
# [('p', 'http://www.wikidata.org/prop/direct/P6104'), ('name', 'maintained by WikiProject')]
# [('p', 'http://www.wikidata.org/prop/direct/P6150'), ('name', 'Academy Awards Database nominee ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6200'), ('name', 'BBC News topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6262'), ('name', 'Fandom article ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6293'), ('name', 'YSA ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6404'), ('name', "Treccani's Dizionario di Storia ID")]
# [('p', 'http://www.wikidata.org/prop/direct/P6413'), ('name', 'JORFSearch organization ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P646'), ('name', 'Freebase ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6573'), ('name', 'Klexikon article ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6592'), ('name', 'OpenStreetMap zoom level')]
# [('p', 'http://www.wikidata.org/prop/direct/P6766'), ('name', "Who's on First ID")]
# [('p', 'http://www.wikidata.org/prop/direct/P6839'), ('name', 'TV Tropes identifier')]
# [('p', 'http://www.wikidata.org/prop/direct/P6849'), ('name', 'DR topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P691'), ('name', 'NKCR AUT ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7012'), ('name', 'World Encyclopedia of Puppetry Arts ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P706'), ('name', 'located in/on physical feature')]
# [('p', 'http://www.wikidata.org/prop/direct/P7157'), ('name', 'The Top Tens ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7208'), ('name', 'Liber Liber author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7295'), ('name', 'Gregorian calendar start date')]
# [('p', 'http://www.wikidata.org/prop/direct/P7314'), ('name', 'TDV İslam Ansiklopedisi ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7322'), ('name', 'Marine Regions Geographic IDentifier (MRGID)')]
# [('p', 'http://www.wikidata.org/prop/direct/P7422'), ('name', 'minimum temperature record')]
# [('p', 'http://www.wikidata.org/prop/direct/P7471'), ('name', 'iNaturalist place ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P78'), ('name', 'top-level Internet domain')]
# [('p', 'http://www.wikidata.org/prop/direct/P7818'), ('name', 'French Vikidia ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7822'), ('name', 'Italian Vikidia ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7827'), ('name', 'Spanish Vikidia ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7829'), ('name', 'English Vikidia ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7832'), ('name', 'Basque Vikidia ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7850'), ('name', 'Joconde location ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7859'), ('name', 'WorldCat Identities ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7867'), ('name', 'category for maps')]
# [('p', 'http://www.wikidata.org/prop/direct/P7870'), ('name', 'Analysis & Policy Observatory term ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7960'), ('name', 'Joconde discovery ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7982'), ('name', 'Hrvatska enciklopedija ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8061'), ('name', 'AGROVOC ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8217'), ('name', 'iDAI.gazetteer ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8309'), ('name', 'Yle topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P832'), ('name', 'public holiday')]
# [('p', 'http://www.wikidata.org/prop/direct/P8349'), ('name', 'Proleksis enciklopedija ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8402'), ('name', 'open data portal')]
# [('p', 'http://www.wikidata.org/prop/direct/P8406'), ('name', 'Grove Art Online ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8408'), ('name', 'KBpedia ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8432'), ('name', 'Österreichisches Musiklexikon Online ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8472'), ('name', 'Encyclopedie berbere keyword ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P85'), ('name', 'anthem')]
# [('p', 'http://www.wikidata.org/prop/direct/P8519'), ('name', 'RKD thesaurus ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P856'), ('name', 'official website')]
# [('p', 'http://www.wikidata.org/prop/direct/P8744'), ('name', 'economy of topic')]
# [('p', 'http://www.wikidata.org/prop/direct/P8785'), ('name', 'AniDB tag ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8814'), ('name', 'WordNet 3.1 Synset ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8826'), ('name', 'edition humboldt digital ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8885'), ('name', 'Namuwiki ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8895'), ('name', 'All the Tropes identifier')]
# [('p', 'http://www.wikidata.org/prop/direct/P8935'), ('name', 'Encyclopedia of the History of Ukraine ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8974'), ('name', 'SAPA ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P898'), ('name', 'IPA transcription')]
# [('p', 'http://www.wikidata.org/prop/direct/P901'), ('name', 'FIPS 10-4 (countries and regions)')]
# [('p', 'http://www.wikidata.org/prop/direct/P902'), ('name', 'HDS ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P9037'), ('name', 'BHCL UUID')]
# [('p', 'http://www.wikidata.org/prop/direct/P910'), ('name', "topic's main category")]
# [('p', 'http://www.wikidata.org/prop/direct/P9100'), ('name', 'GitHub topic')]
# [('p', 'http://www.wikidata.org/prop/direct/P9123'), ('name', 'Catalan Vikidia ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P92'), ('name', 'main regulatory text')]
# [('p', 'http://www.wikidata.org/prop/direct/P9223'), ('name', 'Provenio UUID')]
# [('p', 'http://www.wikidata.org/prop/direct/P9241'), ('name', 'demographics of topic')]
# [('p', 'http://www.wikidata.org/prop/direct/P9318'), ('name', 'Ávvir topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P935'), ('name', 'Commons gallery')]
# [('p', 'http://www.wikidata.org/prop/direct/P9368'), ('name', 'CNA topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P94'), ('name', 'coat of arms image')]
# [('p', 'http://www.wikidata.org/prop/direct/P948'), ('name', 'page banner')]
# [('p', 'http://www.wikidata.org/prop/direct/P949'), ('name', 'National Library of Israel ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P9545'), ('name', 'Encyclopedia of China Online Database ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P9629'), ('name', 'Armeniapedia ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P9757'), ('name', 'Schoenberg Database of Manuscripts place ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P982'), ('name', 'MusicBrainz area ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P984'), ('name', 'IOC country code')]
# [('p', 'http://www.wikidata.org/prop/direct/P998'), ('name', 'Curlie ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P4589'), ('name', 'Dreadnought Project page')]
# [('p', 'http://www.wikidata.org/prop/direct/P9122'), ('name', 'SportsLogos.net team ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2436'), ('name', 'voltage')]
# 230

# %%
#return currency for Italy
queryString = """
SELECT DISTINCT ?obj ?name
WHERE {
   wd:Q38 wdt:P38 ?obj .
   # get the label
   # ?obj sc:name ?name.
}
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('obj', 'http://www.wikidata.org/entity/Q4916'), ('name', 'euro')]
# 1

# %%
#return what euro is instance of
queryString = """
SELECT DISTINCT ?obj ?name
WHERE {
   wd:Q4916 wdt:P31 ?obj .
   # get the label
   # ?obj sc:name ?name.
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('obj', 'http://www.wikidata.org/entity/Q28795800'), ('name', 'decimal currency')]
# [('obj', 'http://www.wikidata.org/entity/Q8142'), ('name', 'currency')]
# 2

# %% [markdown]
# Final query for this task

# %%
# write your final query
queryString = """
SELECT DISTINCT ?obj ?name
WHERE {
   wd:Q4916 wdt:P31 ?obj .
   # get the label
   # ?obj sc:name ?name.
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('obj', 'http://www.wikidata.org/entity/Q28795800'), ('name', 'decimal currency')]
# [('obj', 'http://www.wikidata.org/entity/Q8142'), ('name', 'currency')]
# 2

# %% [markdown]
# ## Task 2
# Return the countries which currently use Euro

# %%
# return countries with link currency to Euro
queryString = """
SELECT DISTINCT ?s ?name
WHERE {
   # ?s wdt:P38 wd:Q4916 .
   # get the label
   # ?s sc:name ?name.
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('s', 'http://www.wikidata.org/entity/Q1628531'), ('name', 'Quintanar de la Orden')]
# [('s', 'http://www.wikidata.org/entity/Q673727'), ('name', 'Neudau')]
# [('s', 'http://www.wikidata.org/entity/Q28124876'), ('name', 'Ilmspan')]
# [('s', 'http://www.wikidata.org/entity/Q11959'), ('name', 'Alicante')]
# [('s', 'http://www.wikidata.org/entity/Q25362'), ('name', 'Saint Barthélemy')]
# [('s', 'http://www.wikidata.org/entity/Q17054'), ('name', 'Martinique')]
# [('s', 'http://www.wikidata.org/entity/Q656699'), ('name', 'Montsoreau')]
# [('s', 'http://www.wikidata.org/entity/Q624511'), ('name', 'Aracena')]
# [('s', 'http://www.wikidata.org/entity/Q1246'), ('name', 'Kosovo')]
# [('s', 'http://www.wikidata.org/entity/Q126125'), ('name', 'Saint Martin (French part)')]
# [('s', 'http://www.wikidata.org/entity/Q129003'), ('name', 'French Southern and Antarctic Lands')]
# [('s', 'http://www.wikidata.org/entity/Q13116'), ('name', 'Benelux')]
# [('s', 'http://www.wikidata.org/entity/Q142'), ('name', 'France')]
# [('s', 'http://www.wikidata.org/entity/Q183'), ('name', 'Germany')]
# [('s', 'http://www.wikidata.org/entity/Q191'), ('name', 'Estonia')]
# [('s', 'http://www.wikidata.org/entity/Q1943433'), ('name', 'Molenwaard')]
# [('s', 'http://www.wikidata.org/entity/Q211'), ('name', 'Latvia')]
# [('s', 'http://www.wikidata.org/entity/Q212429'), ('name', 'Metropolitan France')]
# [('s', 'http://www.wikidata.org/entity/Q214'), ('name', 'Slovakia')]
# [('s', 'http://www.wikidata.org/entity/Q215'), ('name', 'Slovenia')]
# [('s', 'http://www.wikidata.org/entity/Q228'), ('name', 'Andorra')]
# [('s', 'http://www.wikidata.org/entity/Q229'), ('name', 'Cyprus')]
# [('s', 'http://www.wikidata.org/entity/Q233'), ('name', 'Malta')]
# [('s', 'http://www.wikidata.org/entity/Q235'), ('name', 'Monaco')]
# [('s', 'http://www.wikidata.org/entity/Q236'), ('name', 'Montenegro')]
# [('s', 'http://www.wikidata.org/entity/Q237'), ('name', 'Vatican City')]
# [('s', 'http://www.wikidata.org/entity/Q238'), ('name', 'San Marino')]
# [('s', 'http://www.wikidata.org/entity/Q25263'), ('name', 'Azores')]
# [('s', 'http://www.wikidata.org/entity/Q27'), ('name', 'Ireland')]
# [('s', 'http://www.wikidata.org/entity/Q29'), ('name', 'Spain')]
# [('s', 'http://www.wikidata.org/entity/Q29999'), ('name', 'Kingdom of the Netherlands')]
# [('s', 'http://www.wikidata.org/entity/Q31'), ('name', 'Belgium')]
# [('s', 'http://www.wikidata.org/entity/Q32'), ('name', 'Luxembourg')]
# [('s', 'http://www.wikidata.org/entity/Q33'), ('name', 'Finland')]
# [('s', 'http://www.wikidata.org/entity/Q37'), ('name', 'Lithuania')]
# [('s', 'http://www.wikidata.org/entity/Q3769'), ('name', 'French Guiana')]
# [('s', 'http://www.wikidata.org/entity/Q38'), ('name', 'Italy')]
# [('s', 'http://www.wikidata.org/entity/Q40'), ('name', 'Austria')]
# [('s', 'http://www.wikidata.org/entity/Q41'), ('name', 'Greece')]
# [('s', 'http://www.wikidata.org/entity/Q45'), ('name', 'Portugal')]
# [('s', 'http://www.wikidata.org/entity/Q458'), ('name', 'European Union')]
# [('s', 'http://www.wikidata.org/entity/Q55'), ('name', 'Netherlands')]
# [('s', 'http://www.wikidata.org/entity/Q5705'), ('name', 'Catalonia')]
# [('s', 'http://www.wikidata.org/entity/Q67585'), ('name', 'Münchringen')]
# [('s', 'http://www.wikidata.org/entity/Q720507'), ('name', 'economy of the European Union')]
# [('s', 'http://www.wikidata.org/entity/Q8062'), ('name', 'economy of the Republic of Ireland')]
# [('s', 'http://www.wikidata.org/entity/Q8268'), ('name', 'Eurozone')]
# [('s', 'http://www.wikidata.org/entity/Q869882'), ('name', 'Noyales')]
# [('s', 'http://www.wikidata.org/entity/Q12258'), ('name', 'Sabadell')]
# [('s', 'http://www.wikidata.org/entity/Q17012'), ('name', 'Guadeloupe')]
# [('s', 'http://www.wikidata.org/entity/Q17070'), ('name', 'Réunion')]
# [('s', 'http://www.wikidata.org/entity/Q5689'), ('name', 'Åland')]
# [('s', 'http://www.wikidata.org/entity/Q936563'), ('name', 'Italian Bourse')]
# [('s', 'http://www.wikidata.org/entity/Q649612'), ('name', 'Coca')]
# [('s', 'http://www.wikidata.org/entity/Q1150680'), ('name', 'Republic of Montenegro')]
# [('s', 'http://www.wikidata.org/entity/Q4513926'), ('name', 'Montenegro Stock Exchange')]
# [('s', 'http://www.wikidata.org/entity/Q1771153'), ('name', 'Albuixech')]
# [('s', 'http://www.wikidata.org/entity/Q4502305'), ('name', 'Huma')]
# [('s', 'http://www.wikidata.org/entity/Q17063'), ('name', 'Mayotte')]
# [('s', 'http://www.wikidata.org/entity/Q37024'), ('name', 'Serbia and Montenegro')]
# [('s', 'http://www.wikidata.org/entity/Q34617'), ('name', 'Saint Pierre and Miquelon')]
# [('s', 'http://www.wikidata.org/entity/Q2982948'), ('name', 'European Collectivity of Alsace')]
# [('s', 'http://www.wikidata.org/entity/Q755341'), ('name', 'Athens Exchange')]
# [('s', 'http://www.wikidata.org/entity/Q686790'), ('name', 'Mediona')]
# [('s', 'http://www.wikidata.org/entity/Q1444150'), ('name', 'Alboloduy')]
# [('s', 'http://www.wikidata.org/entity/Q917883'), ('name', 'Molina de Segura')]
# [('s', 'http://www.wikidata.org/entity/Q1726029'), ('name', 'canton of Lézardrieux')]
# [('s', 'http://www.wikidata.org/entity/Q1631311'), ('name', 'Cuéllar')]
# [('s', 'http://www.wikidata.org/entity/Q1769772'), ('name', 'Bierge / Biarche')]
# [('s', 'http://www.wikidata.org/entity/Q628991'), ('name', 'Tamariz de Campos')]
# [('s', 'http://www.wikidata.org/entity/Q3777251'), ('name', 'Leap card')]
# [('s', 'http://www.wikidata.org/entity/Q112558'), ('name', 'Republic of Saugeais')]
# [('s', 'http://www.wikidata.org/entity/Q34234153'), ('name', 'Liberapay')]
# [('s', 'http://www.wikidata.org/entity/Q8050'), ('name', 'economy of Spain')]
# [('s', 'http://www.wikidata.org/entity/Q8057'), ('name', 'economy of France')]
# [('s', 'http://www.wikidata.org/entity/Q28124877'), ('name', 'Schönfeld')]
# [('s', 'http://www.wikidata.org/entity/Q61928556'), ('name', 'Rauenberg')]
# [('s', 'http://www.wikidata.org/entity/Q28124875'), ('name', 'Gerchsheim')]
# [('s', 'http://www.wikidata.org/entity/Q8085'), ('name', 'economy of Austria')]
# [('s', 'http://www.wikidata.org/entity/Q7942521'), ('name', 'Voyvodovo, Haskovo Province')]
# [('s', 'http://www.wikidata.org/entity/Q138837'), ('name', 'Catalan Republic')]
# [('s', 'http://www.wikidata.org/entity/Q190571'), ('name', 'Scattered Islands in the Indian Ocean')]
# [('s', 'http://www.wikidata.org/entity/Q1644430'), ('name', 'Monreal del Campo')]
# [('s', 'http://www.wikidata.org/entity/Q39486975'), ('name', 'EUR/USD')]
# [('s', 'http://www.wikidata.org/entity/Q39486982'), ('name', 'EUR/JPY')]
# [('s', 'http://www.wikidata.org/entity/Q1026524'), ('name', 'Hivange')]
# [('s', 'http://www.wikidata.org/entity/Q1299355'), ('name', 'economy of Slovenia')]
# [('s', 'http://www.wikidata.org/entity/Q9031607'), ('name', 'BME Growth')]
# [('s', 'http://www.wikidata.org/entity/Q73330139'), ('name', 'Verdis')]
# [('s', 'http://www.wikidata.org/entity/Q98834701'), ('name', 'Adriatic Bank')]
# [('s', 'http://www.wikidata.org/entity/Q39486984'), ('name', 'EUR/GBP')]
# [('s', 'http://www.wikidata.org/entity/Q1423680'), ('name', 'Gay and Lesbian Kingdom of the Coral Sea Islands')]
# 92

# %%
# return nodes which have Italy linked by instance of
queryString = """
SELECT DISTINCT ?o ?name
WHERE {
   wd:Q38 wdt:P31 ?o.
   # get the label
   # ?o sc:name ?name.
}
LIMIT 200
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('o', 'http://www.wikidata.org/entity/Q3624078'), ('name', 'sovereign state')]
# [('o', 'http://www.wikidata.org/entity/Q6256'), ('name', 'country')]
# 2

# %%
## return nodes instance of country with link currency to Euro
queryString = """
SELECT DISTINCT ?s ?name
WHERE {
   # ?s wdt:P31 wd:Q6256;
      wdt:P38 wd:Q4916.
   # get the label
   # ?s sc:name ?name.
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('s', 'http://www.wikidata.org/entity/Q142'), ('name', 'France')]
# [('s', 'http://www.wikidata.org/entity/Q211'), ('name', 'Latvia')]
# [('s', 'http://www.wikidata.org/entity/Q214'), ('name', 'Slovakia')]
# [('s', 'http://www.wikidata.org/entity/Q228'), ('name', 'Andorra')]
# [('s', 'http://www.wikidata.org/entity/Q229'), ('name', 'Cyprus')]
# [('s', 'http://www.wikidata.org/entity/Q233'), ('name', 'Malta')]
# [('s', 'http://www.wikidata.org/entity/Q236'), ('name', 'Montenegro')]
# [('s', 'http://www.wikidata.org/entity/Q27'), ('name', 'Ireland')]
# [('s', 'http://www.wikidata.org/entity/Q29999'), ('name', 'Kingdom of the Netherlands')]
# [('s', 'http://www.wikidata.org/entity/Q33'), ('name', 'Finland')]
# [('s', 'http://www.wikidata.org/entity/Q38'), ('name', 'Italy')]
# [('s', 'http://www.wikidata.org/entity/Q40'), ('name', 'Austria')]
# [('s', 'http://www.wikidata.org/entity/Q41'), ('name', 'Greece')]
# [('s', 'http://www.wikidata.org/entity/Q45'), ('name', 'Portugal')]
# [('s', 'http://www.wikidata.org/entity/Q55'), ('name', 'Netherlands')]
# 15

# %%
#return subproperties of currency
queryString = """
SELECT DISTINCT ?s ?name
WHERE {
   # ?s wdt:P1647 wdt:P38.
   # get the label
   # ?s sc:name ?name.
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# Empty

# %%
#return properties for country (wrong variable)
queryString = """
SELECT DISTINCT ?p ?name
WHERE {
   wd:Q6256 ?p ?o.
   # get the label
   # ?s sc:name ?name.
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), ('name', 'software version identifier')]
# [('p', 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), ('name', 'tabular software version')]
# [('p', 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), ('name', 'has edition or translation')]
# [('p', 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), ('name', 'Fonsi Nieto')]
# [('p', 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), ('name', "Al Stewart's albums in chronological order")]
# [('p', 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), ('name', 'Category:Adelina Lopes Vieira')]
# [('p', 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), ('name', 'Lubomír Stoklásek')]
# [('p', 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), ('name', 'Ciudad Vieja')]
# [('p', 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), ('name', 'Echániz')]
# [('p', 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), ('name', 'Natuna')]
# [('p', 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), ('name', "Acid Mothers Temple's albums in chronological order")]
# [('p', 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), ('name', 'Relaño')]
# [('p', 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), ('name', '2002 in transport')]
# [('p', 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), ('name', '2006 in transport')]
# [('p', 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), ('name', 'Category:1920 elections in Oceania')]
# [('p', 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), ('name', 'Category:2002 elections in South America')]
# [('p', 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), ('name', 'Category:Teluk Sebong')]
# [('p', 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), ('name', 'Võnnu Rural Municipality')]
# [('p', 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), ('name', 'Kojiro Kobayashi')]
# [('p', 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), ('name', 'Miguel E. M. Herrera')]
# [('p', 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), ('name', 'Category:Akita Shoten magazines')]
# [('p', 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), ('name', "2010 CONCACAF Women's Gold Cup")]
# [('p', 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), ('name', '2014 FIFA World Cup venues')]
# [('p', 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), ('name', 'ambassador of Guatemala to France')]
# [('p', 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), ('name', 'Estação Ferroviária de Mafra')]
# [('p', 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), ('name', 'Faculdade de Letras da Universidade de Coimbra')]
# [('p', 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), ('name', 'Faculty of Arts and Humanities of the University of Porto')]
# [('p', 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), ('name', 'Aji')]
# [('p', 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), ('name', 'Urucu')]
# [('p', 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), ('name', 'jikimiyake')]
# [('p', 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), ('name', 'war horse')]
# [('p', 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), ('name', '2010 Pacific hurricane season')]
# [('p', 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), ('name', '1972 in economics')]
# [('p', 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), ('name', '2020 Winter Youth Olympics')]
# [('p', 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), ('name', 'Hitachi Province')]
# [('p', 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), ('name', 'Lightiella')]
# [('p', 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), ('name', 'compilation album released this year')]
# [('p', 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), ('name', 'region of Ethiopia')]
# [('p', 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), ('name', 'Mateo Egea')]
# [('p', 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), ('name', '1942 in meteorology')]
# [('p', 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), ('name', '1958 in meteorology')]
# [('p', 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), ('name', '1964 in meteorology')]
# [('p', 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), ('name', '1971 in meteorology')]
# [('p', 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), ('name', '1989 in meteorology')]
# [('p', 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), ('name', '2000 in meteorology')]
# [('p', 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), ('name', '2003 in meteorology')]
# [('p', 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), ('name', 'Nemėžis')]
# [('p', 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), ('name', '530 BC')]
# [('p', 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), ('name', 'ambassador of China to Peru')]
# [('p', 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), ('name', 'Pleomothra')]
# [('p', 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), ('name', '1967 in politics')]
# [('p', 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), ('name', '1970 FIFA World Cup qualification')]
# [('p', 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), ('name', 'List of ambassadors of Gabon to the United States')]
# [('p', 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), ('name', 'Vietnamese name')]
# [('p', 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), ('name', '2003 in the Democratic Republic of the Congo')]
# [('p', 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), ('name', '2000 in the Democratic Republic of the Congo')]
# [('p', 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), ('name', 'List of ANZ Championship players')]
# [('p', 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), ('name', 'veterinary scientist')]
# [('p', 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), ('name', 'Suctobelbella')]
# [('p', 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), ('name', 'Versailles EPs discography')]
# [('p', 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), ('name', '2014 in Namibia')]
# [('p', 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), ('name', '1975 in sports')]
# [('p', 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), ('name', "Aaliyah's albums in chronological order")]
# [('p', 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), ('name', 'Jerónimo Latorre')]
# [('p', 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), ('name', '2000 in Uganda')]
# [('p', 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), ('name', 'Paratge natural municipal')]
# [('p', 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), ('name', '1972 in sports')]
# [('p', 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), ('name', 'Alma Scots baseball')]
# [('p', 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), ('name', 'Alfred Saxons football')]
# [('p', 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), ('name', '1987 in sports')]
# [('p', 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), ('name', '1928 in sports')]
# [('p', 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), ('name', '2010 World Touring Car Championship season')]
# [('p', 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), ('name', '2004 UEFA European Under-17 Football Championship')]
# [('p', 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), ('name', '2012 in Vietnam')]
# [('p', 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), ('name', '1984 in Taiwan')]
# [('p', 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), ('name', 'Green Garden Pop')]
# [('p', 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), ('name', 'Kakyuusei 2')]
# [('p', 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), ('name', 'List of ambassador of China to Peru')]
# [('p', 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), ('name', '1994 in sports')]
# [('p', 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), ('name', 'tidal locking')]
# [('p', 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), ('name', '1998 in sports')]
# [('p', 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), ('name', 'Aegadian Islands')]
# [('p', 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), ('name', 'Vice President of the Maldives')]
# [('p', 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), ('name', 'Prince Qing')]
# [('p', 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), ('name', "Grey's Anatomy, season 1")]
# [('p', 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), ('name', 'Category:2009 in Australian sport')]
# [('p', 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), ('name', '1990 in volleyball')]
# [('p', 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), ('name', '1998 in education')]
# [('p', 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), ('name', '2016 in transport')]
# [('p', 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), ('name', '1995 UCI Track Cycling World Championships')]
# [('p', 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), ('name', 'Tokyo Solamachi')]
# [('p', 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), ('name', 'Kubuntu')]
# [('p', 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), ('name', 'The Village Gate')]
# [('p', 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), ('name', 'Orix Real Estate')]
# [('p', 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), ('name', "All People's Party")]
# [('p', 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), ('name', 'Sliven Province')]
# [('p', 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), ('name', 'list of Vegalta Sendai players')]
# [('p', 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), ('name', 'Shimo-Umi Station')]
# [('p', 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), ('name', '2009–2010 Coupe de France')]
# [('p', 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), ('name', 'Bingo-nada')]
# 100

# %%
#return properties for country 
queryString = """
SELECT DISTINCT ?p ?name
WHERE {
   wd:Q6256 ?p ?o.
   # get the label
   # ?p sc:name ?name.
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P1014'), ('name', 'Art & Architecture Thesaurus ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1036'), ('name', 'Dewey Decimal Classification')]
# [('p', 'http://www.wikidata.org/prop/direct/P1051'), ('name', 'PSH ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1151'), ('name', "topic's main Wikimedia portal")]
# [('p', 'http://www.wikidata.org/prop/direct/P1245'), ('name', 'OmegaWiki Defined Meaning')]
# [('p', 'http://www.wikidata.org/prop/direct/P1282'), ('name', 'OpenStreetMap tag or key')]
# [('p', 'http://www.wikidata.org/prop/direct/P1417'), ('name', 'Encyclopædia Britannica Online ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1424'), ('name', "topic's main template")]
# [('p', 'http://www.wikidata.org/prop/direct/P150'), ('name', 'contains administrative territorial entity')]
# [('p', 'http://www.wikidata.org/prop/direct/P1687'), ('name', 'Wikidata property')]
# [('p', 'http://www.wikidata.org/prop/direct/P1709'), ('name', 'equivalent class')]
# [('p', 'http://www.wikidata.org/prop/direct/P18'), ('name', 'image')]
# [('p', 'http://www.wikidata.org/prop/direct/P1889'), ('name', 'different from')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('name', 'properties for this type')]
# [('p', 'http://www.wikidata.org/prop/direct/P227'), ('name', 'GND ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2347'), ('name', 'YSO ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2452'), ('name', 'GeoNames feature code')]
# [('p', 'http://www.wikidata.org/prop/direct/P2581'), ('name', 'BabelNet ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2670'), ('name', 'has parts of the class')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('name', 'subclass of')]
# [('p', 'http://www.wikidata.org/prop/direct/P2888'), ('name', 'exact match')]
# [('p', 'http://www.wikidata.org/prop/direct/P2959'), ('name', 'permanent duplicated item')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('name', 'instance of')]
# [('p', 'http://www.wikidata.org/prop/direct/P3219'), ('name', 'Encyclopædia Universalis ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3417'), ('name', 'Quora topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3553'), ('name', 'Zhihu topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P373'), ('name', 'Commons category')]
# [('p', 'http://www.wikidata.org/prop/direct/P3827'), ('name', 'JSTOR topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3896'), ('name', 'geoshape')]
# [('p', 'http://www.wikidata.org/prop/direct/P443'), ('name', 'pronunciation audio')]
# [('p', 'http://www.wikidata.org/prop/direct/P4527'), ('name', 'UK Parliament thesaurus ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P460'), ('name', 'said to be the same as')]
# [('p', 'http://www.wikidata.org/prop/direct/P5008'), ('name', 'on focus list of Wikimedia project')]
# [('p', 'http://www.wikidata.org/prop/direct/P5250'), ('name', 'IAB code')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('name', 'has part')]
# [('p', 'http://www.wikidata.org/prop/direct/P5869'), ('name', 'model item')]
# [('p', 'http://www.wikidata.org/prop/direct/P6104'), ('name', 'maintained by WikiProject')]
# [('p', 'http://www.wikidata.org/prop/direct/P6186'), ('name', 'category for eponymous categories')]
# [('p', 'http://www.wikidata.org/prop/direct/P646'), ('name', 'Freebase ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7033'), ('name', 'Australian Educational Vocabulary ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7497'), ('name', 'Wolfram Language entity type')]
# [('p', 'http://www.wikidata.org/prop/direct/P7502'), ('name', 'Golden ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7771'), ('name', 'PersonalData.IO ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7818'), ('name', 'French Vikidia ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7827'), ('name', 'Spanish Vikidia ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8408'), ('name', 'KBpedia ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8834'), ('name', 'MetaSat ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P910'), ('name', "topic's main category")]
# [('p', 'http://www.wikidata.org/prop/direct/P973'), ('name', 'described at URL')]
# 49

# %%
#return nodes subclass of country
queryString = """
SELECT DISTINCT ?s ?name
WHERE {
   # ?s wdt:P279  wd:Q6256.
   # get the label
   # ?s sc:name ?name.
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('s', 'http://www.wikidata.org/entity/Q28864179'), ('name', 'proposed country')]
# [('s', 'http://www.wikidata.org/entity/Q2281140'), ('name', 'safe country of origin')]
# [('s', 'http://www.wikidata.org/entity/Q188800'), ('name', 'personal union')]
# [('s', 'http://www.wikidata.org/entity/Q1323642'), ('name', 'transcontinental country')]
# [('s', 'http://www.wikidata.org/entity/Q132453'), ('name', 'developed country')]
# [('s', 'http://www.wikidata.org/entity/Q177323'), ('name', 'developing country')]
# [('s', 'http://www.wikidata.org/entity/Q5170193'), ('name', 'core country')]
# [('s', 'http://www.wikidata.org/entity/Q63441421'), ('name', 'high-income country')]
# [('s', 'http://www.wikidata.org/entity/Q160381'), ('name', 'Western world')]
# [('s', 'http://www.wikidata.org/entity/Q112099'), ('name', 'island nation')]
# [('s', 'http://www.wikidata.org/entity/Q123480'), ('name', 'landlocked country')]
# [('s', 'http://www.wikidata.org/entity/Q3624078'), ('name', 'sovereign state')]
# [('s', 'http://www.wikidata.org/entity/Q51576574'), ('name', 'Mediterranean country')]
# [('s', 'http://www.wikidata.org/entity/Q11396118'), ('name', 'divided country')]
# [('s', 'http://www.wikidata.org/entity/Q1501897'), ('name', 'Generality Lands')]
# [('s', 'http://www.wikidata.org/entity/Q1454602'), ('name', 'low-income country')]
# [('s', 'http://www.wikidata.org/entity/Q1093720'), ('name', 'real union')]
# [('s', 'http://www.wikidata.org/entity/Q331644'), ('name', 'Khanate')]
# [('s', 'http://www.wikidata.org/entity/Q1151616'), ('name', 'stateless nation')]
# [('s', 'http://www.wikidata.org/entity/Q7449317'), ('name', 'semi-periphery countries')]
# [('s', 'http://www.wikidata.org/entity/Q11495981'), ('name', 'victorious country')]
# [('s', 'http://www.wikidata.org/entity/Q831048'), ('name', 'Nassau-Hadamar')]
# [('s', 'http://www.wikidata.org/entity/Q66724388'), ('name', 'autonomous country within the Kingdom of Denmark')]
# [('s', 'http://www.wikidata.org/entity/Q25449457'), ('name', 'continental country')]
# [('s', 'http://www.wikidata.org/entity/Q5367717'), ('name', 'shinkoku')]
# [('s', 'http://www.wikidata.org/entity/Q1641089'), ('name', 'Multinational state')]
# [('s', 'http://www.wikidata.org/entity/Q2639564'), ('name', 'low-wage country')]
# [('s', 'http://www.wikidata.org/entity/Q6726158'), ('name', 'Independent country')]
# [('s', 'http://www.wikidata.org/entity/Q1538989'), ('name', 'megadiverse country')]
# [('s', 'http://www.wikidata.org/entity/Q66903706'), ('name', 'banana producing countries')]
# [('s', 'http://www.wikidata.org/entity/Q3500085'), ('name', 'periphery country')]
# [('s', 'http://www.wikidata.org/entity/Q3373662'), ('name', 'French-speaking country')]
# 32

# %%
# return nodes which have Kingdom of the Netherlands linked by instance of
queryString = """
SELECT DISTINCT ?o ?name
WHERE {
   wd:Q29999 wdt:P31 ?o.
   # get the label
   # ?o sc:name ?name.
}
LIMIT 200
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('o', 'http://www.wikidata.org/entity/Q20181813'), ('name', 'colonial power')]
# [('o', 'http://www.wikidata.org/entity/Q3624078'), ('name', 'sovereign state')]
# [('o', 'http://www.wikidata.org/entity/Q6256'), ('name', 'country')]
# [('o', 'http://www.wikidata.org/entity/Q417175'), ('name', 'kingdom')]
# 4

# %%
#return all the properties linking Kingdom of the Netherlands and Netherlands
queryString = """
SELECT DISTINCT ?p ?name
WHERE {
   # bind something
   wd:Q29999 ?p wd:Q55.
   # get the label
   # ?p sc:name ?name.
}
LIMIT 500
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P150'), ('name', 'contains administrative territorial entity')]
# [('p', 'http://www.wikidata.org/prop/direct/P1889'), ('name', 'different from')]
# 2

# %%
# return nodes which have Netherlands linked by instance of
queryString = """
SELECT DISTINCT ?o ?name
WHERE {
   wd:Q55 wdt:P31 ?o.
   # get the label
   # ?o sc:name ?name.
}
LIMIT 200
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('o', 'http://www.wikidata.org/entity/Q6256'), ('name', 'country')]
# [('o', 'http://www.wikidata.org/entity/Q15304003'), ('name', 'country of the Kingdom of the Netherlands')]
# 2

# %%
# return nodes with link country to country and link currency to Euro (some countries are missing like Germany, Spain)
queryString = """
SELECT DISTINCT ?s ?name
WHERE {
   # ?s wdt:P17 wd:Q6256;
      wdt:P38 wd:Q4916.
   # get the label
   # ?s sc:name ?name.
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# Empty

# %%
#return objects having subject Italy and property country
queryString = """
SELECT DISTINCT ?o ?name
WHERE {
   wd:Q38 wdt:P17 ?o.
   # get the label
   # ?o sc:name ?name.
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('o', 'http://www.wikidata.org/entity/Q38'), ('name', 'Italy')]
# 1

# %%
#return nodes which have country Italy
queryString = """
SELECT DISTINCT ?s ?name
WHERE {
   # ?s wdt:P17 wd:Q38.
   # get the label
   # ?s sc:name ?name.
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('s', 'http://www.wikidata.org/entity/Q109576'), ('name', 'Aegadian Islands')]
# [('s', 'http://www.wikidata.org/entity/Q3800298'), ('name', '1992 Italian Open')]
# [('s', 'http://www.wikidata.org/entity/Q3857666'), ('name', '1990 Stella Artois Indoor')]
# [('s', 'http://www.wikidata.org/entity/Q48851233'), ('name', 'Algeria–Italy relations')]
# [('s', 'http://www.wikidata.org/entity/Q7920527'), ('name', 'Venues of the 2006 Winter Olympics')]
# [('s', 'http://www.wikidata.org/entity/Q895799'), ('name', '2009 World Amateur Boxing Championships')]
# [('s', 'http://www.wikidata.org/entity/Q923273'), ('name', '2005 UEFA European Under-17 Football Championship')]
# [('s', 'http://www.wikidata.org/entity/Q47176'), ('name', 'Lombard cuisine')]
# [('s', 'http://www.wikidata.org/entity/Q4850939'), ('name', 'Years of Lead')]
# [('s', 'http://www.wikidata.org/entity/Q5258020'), ('name', 'Denmark–Italy relations')]
# [('s', 'http://www.wikidata.org/entity/Q5354766'), ('name', 'elections in Molise')]
# [('s', 'http://www.wikidata.org/entity/Q5354825'), ('name', 'elections in Sicily')]
# [('s', 'http://www.wikidata.org/entity/Q1814125'), ('name', 'Schema Records')]
# [('s', 'http://www.wikidata.org/entity/Q3867532'), ('name', 'list of museums in Calabria')]
# [('s', 'http://www.wikidata.org/entity/Q3972173'), ('name', 'Railway stations in Genoa')]
# [('s', 'http://www.wikidata.org/entity/Q3972185'), ('name', 'Railway stations in Milan')]
# [('s', 'http://www.wikidata.org/entity/Q4987658'), ('name', 'list of railway stations in Lazio')]
# [('s', 'http://www.wikidata.org/entity/Q6636012'), ('name', 'list of railway stations in Abruzzo')]
# [('s', 'http://www.wikidata.org/entity/Q6636070'), ('name', 'list of railway stations in Molise')]
# [('s', 'http://www.wikidata.org/entity/Q6636073'), ('name', 'list of railway stations in Sardinia')]
# [('s', 'http://www.wikidata.org/entity/Q6636085'), ('name', 'list of railway stations in Tuscany')]
# [('s', 'http://www.wikidata.org/entity/Q691760'), ('name', 'Mediterranean Grand Prix')]
# [('s', 'http://www.wikidata.org/entity/Q15720771'), ('name', 'Monticchiello')]
# [('s', 'http://www.wikidata.org/entity/Q15755023'), ('name', 'European Journal of Ophthalmology')]
# [('s', 'http://www.wikidata.org/entity/Q15761776'), ('name', 'Journal of Sports Medicine and Physical Fitness')]
# [('s', 'http://www.wikidata.org/entity/Q18590120'), ('name', 'Fabrizio Serra Editore')]
# [('s', 'http://www.wikidata.org/entity/Q3617893'), ('name', "Annali dell'Istituto Superiore di Sanità")]
# [('s', 'http://www.wikidata.org/entity/Q3626845'), ('name', 'A.S.D. Anziolavinio')]
# [('s', 'http://www.wikidata.org/entity/Q3660506'), ('name', 'Carocci Editore')]
# [('s', 'http://www.wikidata.org/entity/Q3860587'), ('name', 'Moncalieri Calcio')]
# [('s', 'http://www.wikidata.org/entity/Q4014901'), ('name', 'Vita e pensiero')]
# [('s', 'http://www.wikidata.org/entity/Q50817801'), ('name', 'The European Zoological Journal')]
# [('s', 'http://www.wikidata.org/entity/Q1272875'), ('name', "D'Angelo & Antenucci-Nippo 2011")]
# [('s', 'http://www.wikidata.org/entity/Q15638144'), ('name', '1989 Coppa Italia Final')]
# [('s', 'http://www.wikidata.org/entity/Q15638152'), ('name', '1987 Coppa Italia Final')]
# [('s', 'http://www.wikidata.org/entity/Q15845585'), ('name', 'Villa Spinola di San Pietro')]
# [('s', 'http://www.wikidata.org/entity/Q15845615'), ('name', '2013–14 San Marino Calcio season')]
# [('s', 'http://www.wikidata.org/entity/Q15850218'), ('name', 'Nippo 2012')]
# [('s', 'http://www.wikidata.org/entity/Q15857922'), ('name', 'Collesalvetti railway station')]
# [('s', 'http://www.wikidata.org/entity/Q15875245'), ('name', '1984 Coppa Italia Final')]
# [('s', 'http://www.wikidata.org/entity/Q15875247'), ('name', '1985 Coppa Italia Final')]
# [('s', 'http://www.wikidata.org/entity/Q15875248'), ('name', '1986 Coppa Italia Final')]
# [('s', 'http://www.wikidata.org/entity/Q15875250'), ('name', '1990 Coppa Italia Final')]
# [('s', 'http://www.wikidata.org/entity/Q15875251'), ('name', '1991 Coppa Italia Final')]
# [('s', 'http://www.wikidata.org/entity/Q15875253'), ('name', '1993 Coppa Italia Final')]
# [('s', 'http://www.wikidata.org/entity/Q15875255'), ('name', '1994 Coppa Italia Final')]
# [('s', 'http://www.wikidata.org/entity/Q15875256'), ('name', '1995 Coppa Italia Final')]
# [('s', 'http://www.wikidata.org/entity/Q15875257'), ('name', '1996 Coppa Italia Final')]
# [('s', 'http://www.wikidata.org/entity/Q15875258'), ('name', '1997 Coppa Italia Final')]
# [('s', 'http://www.wikidata.org/entity/Q15875259'), ('name', '1998 Coppa Italia Final')]
# [('s', 'http://www.wikidata.org/entity/Q15881409'), ('name', "2008 Giro d'Italia, Stage 13")]
# [('s', 'http://www.wikidata.org/entity/Q15881411'), ('name', "2008 Giro d'Italia, Stage 1")]
# [('s', 'http://www.wikidata.org/entity/Q15881423'), ('name', "2008 Giro d'Italia, Stage 5")]
# [('s', 'http://www.wikidata.org/entity/Q15884541'), ('name', 'lettera27')]
# [('s', 'http://www.wikidata.org/entity/Q15917601'), ('name', '1979 Italian general election in Veneto')]
# [('s', 'http://www.wikidata.org/entity/Q15918522'), ('name', '1982–83 A.C. Monza Brianza 1912 season')]
# [('s', 'http://www.wikidata.org/entity/Q15918626'), ('name', 'Cenesi')]
# [('s', 'http://www.wikidata.org/entity/Q16485829'), ('name', '1983–84 A.C. Monza Brianza 1912 season')]
# [('s', 'http://www.wikidata.org/entity/Q17264587'), ('name', 'Carrozzeria Francis Lombardi')]
# [('s', 'http://www.wikidata.org/entity/Q17381081'), ('name', 'Nippo-De Rosa 2013')]
# [('s', 'http://www.wikidata.org/entity/Q17652104'), ('name', '2014–15 San Marino Calcio season')]
# [('s', 'http://www.wikidata.org/entity/Q18844136'), ('name', '1981–82 A.C. Monza Brianza 1912 season')]
# [('s', 'http://www.wikidata.org/entity/Q22917430'), ('name', '2012–13 San Marino Calcio season')]
# [('s', 'http://www.wikidata.org/entity/Q284490'), ('name', '1984–85 Coppa Italia')]
# [('s', 'http://www.wikidata.org/entity/Q29917368'), ('name', 'Livorno–Collesalvetti railway')]
# [('s', 'http://www.wikidata.org/entity/Q29917449'), ('name', 'Nugola Berte railway station')]
# [('s', 'http://www.wikidata.org/entity/Q29917484'), ('name', 'Vicarello railway station')]
# [('s', 'http://www.wikidata.org/entity/Q29917503'), ('name', 'Fauglia-Lorenzana railway station')]
# [('s', 'http://www.wikidata.org/entity/Q3626915'), ('name', 'Associazione Sportiva Dilettantistica Stasia Calcio')]
# [('s', 'http://www.wikidata.org/entity/Q3673045'), ('name', 'Santa Emerenziana a Tor Fiorenza')]
# [('s', 'http://www.wikidata.org/entity/Q3743480'), ('name', 'Pisa–Vada railway')]
# [('s', 'http://www.wikidata.org/entity/Q4587601'), ('name', '1992 Coppa Italia Final')]
# [('s', 'http://www.wikidata.org/entity/Q4603385'), ('name', "2004 UCI Road World Championships – Junior women's road race")]
# [('s', 'http://www.wikidata.org/entity/Q4604154'), ('name', '2005 Coppa Italia Final')]
# [('s', 'http://www.wikidata.org/entity/Q65550575'), ('name', "2014 Italian Junior International Badminton Championships – women's singles")]
# [('s', 'http://www.wikidata.org/entity/Q7209754'), ('name', 'Polimoda')]
# [('s', 'http://www.wikidata.org/entity/Q731778'), ('name', '1992–93 Coppa Italia')]
# [('s', 'http://www.wikidata.org/entity/Q832939'), ('name', "2008 Giro d'Italia")]
# [('s', 'http://www.wikidata.org/entity/Q839806'), ('name', '1993–94 Coppa Italia')]
# [('s', 'http://www.wikidata.org/entity/Q839844'), ('name', '1999–2000 Coppa Italia')]
# [('s', 'http://www.wikidata.org/entity/Q839846'), ('name', '1989–90 Coppa Italia')]
# [('s', 'http://www.wikidata.org/entity/Q839986'), ('name', '1985–86 Coppa Italia')]
# [('s', 'http://www.wikidata.org/entity/Q16024304'), ('name', "2007 Giro d'Italia, Stage 11")]
# [('s', 'http://www.wikidata.org/entity/Q16040699'), ('name', 'Mille Miglia 1929')]
# [('s', 'http://www.wikidata.org/entity/Q1935482'), ('name', 'Mille Miglia')]
# [('s', 'http://www.wikidata.org/entity/Q19631848'), ('name', 'Tempio di San Francesco')]
# [('s', 'http://www.wikidata.org/entity/Q19819048'), ('name', 'Rookies & Kings')]
# [('s', 'http://www.wikidata.org/entity/Q30025480'), ('name', 'Dorno')]
# [('s', 'http://www.wikidata.org/entity/Q599415'), ('name', "2007 Giro d'Italia")]
# [('s', 'http://www.wikidata.org/entity/Q635484'), ('name', 'Armani')]
# [('s', 'http://www.wikidata.org/entity/Q9054484'), ('name', 'Palazzo di Spagna')]
# [('s', 'http://www.wikidata.org/entity/Q1399810'), ('name', '2011 World Fencing Championships')]
# [('s', 'http://www.wikidata.org/entity/Q16040416'), ('name', '1930 Rome Grand Prix')]
# [('s', 'http://www.wikidata.org/entity/Q16218804'), ('name', 'Mittelberg')]
# [('s', 'http://www.wikidata.org/entity/Q3800262'), ('name', '1985 Italian Open')]
# [('s', 'http://www.wikidata.org/entity/Q3820932'), ('name', 'La Lettura')]
# [('s', 'http://www.wikidata.org/entity/Q40940'), ('name', 'Lungavilla')]
# [('s', 'http://www.wikidata.org/entity/Q491782'), ('name', 'Natural Law Party')]
# [('s', 'http://www.wikidata.org/entity/Q67435086'), ('name', '2019 Lombardia Trophy - ice dancing')]
# [('s', 'http://www.wikidata.org/entity/Q7301099'), ('name', 'Real Vicenza')]
# 100

# %%
# return nodes instances of country 
queryString = """
SELECT DISTINCT ?s ?name
WHERE {
   # ?s wdt:P31 wd:Q6256.
   # get the label
   # ?s sc:name ?name.
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('s', 'http://www.wikidata.org/entity/Q16644'), ('name', 'Northern Mariana Islands')]
# [('s', 'http://www.wikidata.org/entity/Q207991'), ('name', 'Pahlavi Dynasty')]
# [('s', 'http://www.wikidata.org/entity/Q756617'), ('name', 'Danish Realm')]
# [('s', 'http://www.wikidata.org/entity/Q786'), ('name', 'Dominican Republic')]
# [('s', 'http://www.wikidata.org/entity/Q907112'), ('name', 'Transnistria')]
# [('s', 'http://www.wikidata.org/entity/Q244165'), ('name', 'Republic of Artsakh')]
# [('s', 'http://www.wikidata.org/entity/Q1005'), ('name', 'The Gambia')]
# [('s', 'http://www.wikidata.org/entity/Q1006'), ('name', 'Guinea')]
# [('s', 'http://www.wikidata.org/entity/Q1007'), ('name', 'Guinea-Bissau')]
# [('s', 'http://www.wikidata.org/entity/Q1008'), ('name', 'Ivory Coast')]
# [('s', 'http://www.wikidata.org/entity/Q1009'), ('name', 'Cameroon')]
# [('s', 'http://www.wikidata.org/entity/Q1011'), ('name', 'Cape Verde')]
# [('s', 'http://www.wikidata.org/entity/Q1013'), ('name', 'Lesotho')]
# [('s', 'http://www.wikidata.org/entity/Q1014'), ('name', 'Liberia')]
# [('s', 'http://www.wikidata.org/entity/Q1016'), ('name', 'Libya')]
# [('s', 'http://www.wikidata.org/entity/Q1019'), ('name', 'Madagascar')]
# [('s', 'http://www.wikidata.org/entity/Q1020'), ('name', 'Malawi')]
# [('s', 'http://www.wikidata.org/entity/Q1025'), ('name', 'Mauritania')]
# [('s', 'http://www.wikidata.org/entity/Q1027'), ('name', 'Mauritius')]
# [('s', 'http://www.wikidata.org/entity/Q1028'), ('name', 'Morocco')]
# [('s', 'http://www.wikidata.org/entity/Q1029'), ('name', 'Mozambique')]
# [('s', 'http://www.wikidata.org/entity/Q1030'), ('name', 'Namibia')]
# [('s', 'http://www.wikidata.org/entity/Q1032'), ('name', 'Niger')]
# [('s', 'http://www.wikidata.org/entity/Q1033'), ('name', 'Nigeria')]
# [('s', 'http://www.wikidata.org/entity/Q1036'), ('name', 'Uganda')]
# [('s', 'http://www.wikidata.org/entity/Q1037'), ('name', 'Rwanda')]
# [('s', 'http://www.wikidata.org/entity/Q1039'), ('name', 'São Tomé and Príncipe')]
# [('s', 'http://www.wikidata.org/entity/Q1041'), ('name', 'Senegal')]
# [('s', 'http://www.wikidata.org/entity/Q1042'), ('name', 'Seychelles')]
# [('s', 'http://www.wikidata.org/entity/Q1044'), ('name', 'Sierra Leone')]
# [('s', 'http://www.wikidata.org/entity/Q1045'), ('name', 'Somalia')]
# [('s', 'http://www.wikidata.org/entity/Q1049'), ('name', 'Sudan')]
# [('s', 'http://www.wikidata.org/entity/Q114'), ('name', 'Kenya')]
# [('s', 'http://www.wikidata.org/entity/Q115'), ('name', 'Ethiopia')]
# [('s', 'http://www.wikidata.org/entity/Q117'), ('name', 'Ghana')]
# [('s', 'http://www.wikidata.org/entity/Q142'), ('name', 'France')]
# [('s', 'http://www.wikidata.org/entity/Q145'), ('name', 'United Kingdom')]
# [('s', 'http://www.wikidata.org/entity/Q148'), ('name', "People's Republic of China")]
# [('s', 'http://www.wikidata.org/entity/Q155'), ('name', 'Brazil')]
# [('s', 'http://www.wikidata.org/entity/Q16'), ('name', 'Canada')]
# [('s', 'http://www.wikidata.org/entity/Q16641'), ('name', 'American Samoa')]
# [('s', 'http://www.wikidata.org/entity/Q17'), ('name', 'Japan')]
# [('s', 'http://www.wikidata.org/entity/Q184'), ('name', 'Belarus')]
# [('s', 'http://www.wikidata.org/entity/Q1852345'), ('name', 'Trucial States')]
# [('s', 'http://www.wikidata.org/entity/Q20'), ('name', 'Norway')]
# [('s', 'http://www.wikidata.org/entity/Q211'), ('name', 'Latvia')]
# [('s', 'http://www.wikidata.org/entity/Q21203'), ('name', 'Aruba')]
# [('s', 'http://www.wikidata.org/entity/Q213'), ('name', 'Czech Republic')]
# [('s', 'http://www.wikidata.org/entity/Q214'), ('name', 'Slovakia')]
# [('s', 'http://www.wikidata.org/entity/Q218'), ('name', 'Romania')]
# [('s', 'http://www.wikidata.org/entity/Q219'), ('name', 'Bulgaria')]
# [('s', 'http://www.wikidata.org/entity/Q222'), ('name', 'Albania')]
# [('s', 'http://www.wikidata.org/entity/Q224'), ('name', 'Croatia')]
# [('s', 'http://www.wikidata.org/entity/Q228'), ('name', 'Andorra')]
# [('s', 'http://www.wikidata.org/entity/Q22880'), ('name', 'Electoral Palatinate')]
# [('s', 'http://www.wikidata.org/entity/Q229'), ('name', 'Cyprus')]
# [('s', 'http://www.wikidata.org/entity/Q232'), ('name', 'Kazakhstan')]
# [('s', 'http://www.wikidata.org/entity/Q233'), ('name', 'Malta')]
# [('s', 'http://www.wikidata.org/entity/Q236'), ('name', 'Montenegro')]
# [('s', 'http://www.wikidata.org/entity/Q241'), ('name', 'Cuba')]
# [('s', 'http://www.wikidata.org/entity/Q244'), ('name', 'Barbados')]
# [('s', 'http://www.wikidata.org/entity/Q25'), ('name', 'Wales')]
# [('s', 'http://www.wikidata.org/entity/Q252'), ('name', 'Indonesia')]
# [('s', 'http://www.wikidata.org/entity/Q258'), ('name', 'South Africa')]
# [('s', 'http://www.wikidata.org/entity/Q262'), ('name', 'Algeria')]
# [('s', 'http://www.wikidata.org/entity/Q26273'), ('name', 'Sint Maarten')]
# [('s', 'http://www.wikidata.org/entity/Q265'), ('name', 'Uzbekistan')]
# [('s', 'http://www.wikidata.org/entity/Q26988'), ('name', 'Cook Islands')]
# [('s', 'http://www.wikidata.org/entity/Q27'), ('name', 'Ireland')]
# [('s', 'http://www.wikidata.org/entity/Q28'), ('name', 'Hungary')]
# [('s', 'http://www.wikidata.org/entity/Q298'), ('name', 'Chile')]
# [('s', 'http://www.wikidata.org/entity/Q29999'), ('name', 'Kingdom of the Netherlands')]
# [('s', 'http://www.wikidata.org/entity/Q30'), ('name', 'United States of America')]
# [('s', 'http://www.wikidata.org/entity/Q33'), ('name', 'Finland')]
# [('s', 'http://www.wikidata.org/entity/Q334'), ('name', 'Singapore')]
# [('s', 'http://www.wikidata.org/entity/Q34'), ('name', 'Sweden')]
# [('s', 'http://www.wikidata.org/entity/Q34020'), ('name', 'Niue')]
# [('s', 'http://www.wikidata.org/entity/Q347'), ('name', 'Liechtenstein')]
# [('s', 'http://www.wikidata.org/entity/Q35'), ('name', 'Denmark')]
# [('s', 'http://www.wikidata.org/entity/Q36'), ('name', 'Poland')]
# [('s', 'http://www.wikidata.org/entity/Q38'), ('name', 'Italy')]
# [('s', 'http://www.wikidata.org/entity/Q39'), ('name', 'Switzerland')]
# [('s', 'http://www.wikidata.org/entity/Q3908'), ('name', 'Galicia')]
# [('s', 'http://www.wikidata.org/entity/Q398'), ('name', 'Bahrain')]
# [('s', 'http://www.wikidata.org/entity/Q40'), ('name', 'Austria')]
# [('s', 'http://www.wikidata.org/entity/Q408'), ('name', 'Australia')]
# [('s', 'http://www.wikidata.org/entity/Q41'), ('name', 'Greece')]
# [('s', 'http://www.wikidata.org/entity/Q414'), ('name', 'Argentina')]
# [('s', 'http://www.wikidata.org/entity/Q419'), ('name', 'Peru')]
# [('s', 'http://www.wikidata.org/entity/Q423'), ('name', 'North Korea')]
# [('s', 'http://www.wikidata.org/entity/Q424'), ('name', 'Cambodia')]
# [('s', 'http://www.wikidata.org/entity/Q43'), ('name', 'Turkey')]
# [('s', 'http://www.wikidata.org/entity/Q45'), ('name', 'Portugal')]
# [('s', 'http://www.wikidata.org/entity/Q55'), ('name', 'Netherlands')]
# [('s', 'http://www.wikidata.org/entity/Q574'), ('name', 'East Timor')]
# [('s', 'http://www.wikidata.org/entity/Q657'), ('name', 'Chad')]
# [('s', 'http://www.wikidata.org/entity/Q664'), ('name', 'New Zealand')]
# [('s', 'http://www.wikidata.org/entity/Q668'), ('name', 'India')]
# [('s', 'http://www.wikidata.org/entity/Q672'), ('name', 'Tuvalu')]
# [('s', 'http://www.wikidata.org/entity/Q683'), ('name', 'Samoa')]
# 100

# %%
# return nodes which have Germany linked by instance of
queryString = """
SELECT DISTINCT ?o ?name
WHERE {
   wd:Q183 wdt:P31 ?o.
   # get the label
   # ?o sc:name ?name.
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('o', 'http://www.wikidata.org/entity/Q3624078'), ('name', 'sovereign state')]
# [('o', 'http://www.wikidata.org/entity/Q4209223'), ('name', 'Rechtsstaat')]
# [('o', 'http://www.wikidata.org/entity/Q43702'), ('name', 'federation')]
# [('o', 'http://www.wikidata.org/entity/Q619610'), ('name', 'social state')]
# [('o', 'http://www.wikidata.org/entity/Q63791824'), ('name', 'country bordering the Baltic Sea')]
# [('o', 'http://www.wikidata.org/entity/Q7270'), ('name', 'republic')]
# 6

# %%
#same for Spain
queryString = """
SELECT DISTINCT ?o ?name
WHERE {
   wd:Q29 wdt:P31 ?o.
   # get the label
   # ?o sc:name ?name.
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('o', 'http://www.wikidata.org/entity/Q3624078'), ('name', 'sovereign state')]
# 1

# %%
#return all sublcasses of country (wrong Q is missing in Q6256)
queryString = """
SELECT DISTINCT ?s ?name
WHERE {
   # ?s wdt:P279 wd:6256.
   # get the label
   # ?s sc:name ?name.
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# Empty

# %%
#return all sublcasses of country 
queryString = """
SELECT DISTINCT ?s ?name
WHERE {
   # ?s wdt:P279 wd:Q6256.
   # get the label
   # ?s sc:name ?name.
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('s', 'http://www.wikidata.org/entity/Q28864179'), ('name', 'proposed country')]
# [('s', 'http://www.wikidata.org/entity/Q2281140'), ('name', 'safe country of origin')]
# [('s', 'http://www.wikidata.org/entity/Q188800'), ('name', 'personal union')]
# [('s', 'http://www.wikidata.org/entity/Q1323642'), ('name', 'transcontinental country')]
# [('s', 'http://www.wikidata.org/entity/Q132453'), ('name', 'developed country')]
# [('s', 'http://www.wikidata.org/entity/Q177323'), ('name', 'developing country')]
# [('s', 'http://www.wikidata.org/entity/Q5170193'), ('name', 'core country')]
# [('s', 'http://www.wikidata.org/entity/Q63441421'), ('name', 'high-income country')]
# [('s', 'http://www.wikidata.org/entity/Q160381'), ('name', 'Western world')]
# [('s', 'http://www.wikidata.org/entity/Q112099'), ('name', 'island nation')]
# [('s', 'http://www.wikidata.org/entity/Q123480'), ('name', 'landlocked country')]
# [('s', 'http://www.wikidata.org/entity/Q3624078'), ('name', 'sovereign state')]
# [('s', 'http://www.wikidata.org/entity/Q51576574'), ('name', 'Mediterranean country')]
# [('s', 'http://www.wikidata.org/entity/Q11396118'), ('name', 'divided country')]
# [('s', 'http://www.wikidata.org/entity/Q1501897'), ('name', 'Generality Lands')]
# [('s', 'http://www.wikidata.org/entity/Q1454602'), ('name', 'low-income country')]
# [('s', 'http://www.wikidata.org/entity/Q1093720'), ('name', 'real union')]
# [('s', 'http://www.wikidata.org/entity/Q331644'), ('name', 'Khanate')]
# [('s', 'http://www.wikidata.org/entity/Q1151616'), ('name', 'stateless nation')]
# [('s', 'http://www.wikidata.org/entity/Q7449317'), ('name', 'semi-periphery countries')]
# [('s', 'http://www.wikidata.org/entity/Q11495981'), ('name', 'victorious country')]
# [('s', 'http://www.wikidata.org/entity/Q831048'), ('name', 'Nassau-Hadamar')]
# [('s', 'http://www.wikidata.org/entity/Q66724388'), ('name', 'autonomous country within the Kingdom of Denmark')]
# [('s', 'http://www.wikidata.org/entity/Q25449457'), ('name', 'continental country')]
# [('s', 'http://www.wikidata.org/entity/Q5367717'), ('name', 'shinkoku')]
# [('s', 'http://www.wikidata.org/entity/Q1641089'), ('name', 'Multinational state')]
# [('s', 'http://www.wikidata.org/entity/Q2639564'), ('name', 'low-wage country')]
# [('s', 'http://www.wikidata.org/entity/Q6726158'), ('name', 'Independent country')]
# [('s', 'http://www.wikidata.org/entity/Q1538989'), ('name', 'megadiverse country')]
# [('s', 'http://www.wikidata.org/entity/Q66903706'), ('name', 'banana producing countries')]
# [('s', 'http://www.wikidata.org/entity/Q3500085'), ('name', 'periphery country')]
# [('s', 'http://www.wikidata.org/entity/Q3373662'), ('name', 'French-speaking country')]
# 32

# %%
#return all sublcasses of sovereign state
queryString = """
SELECT DISTINCT ?s ?name
WHERE {
   # ?s wdt:P279 wd:Q3624078.
   # get the label
   # ?s sc:name ?name.
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('s', 'http://www.wikidata.org/entity/Q160016'), ('name', 'member states of the United Nations')]
# [('s', 'http://www.wikidata.org/entity/Q189062'), ('name', 'states with nuclear weapons')]
# [('s', 'http://www.wikidata.org/entity/Q20181813'), ('name', 'colonial power')]
# [('s', 'http://www.wikidata.org/entity/Q48349'), ('name', 'empire')]
# [('s', 'http://www.wikidata.org/entity/Q51576574'), ('name', 'Mediterranean country')]
# [('s', 'http://www.wikidata.org/entity/Q63791824'), ('name', 'country bordering the Baltic Sea')]
# [('s', 'http://www.wikidata.org/entity/Q7840353'), ('name', 'federally recognized Native American tribe in the United States')]
# [('s', 'http://www.wikidata.org/entity/Q244381'), ('name', 'microstate')]
# [('s', 'http://www.wikidata.org/entity/Q202686'), ('name', 'Commonwealth realm')]
# [('s', 'http://www.wikidata.org/entity/Q179671'), ('name', 'nation state')]
# [('s', 'http://www.wikidata.org/entity/Q25449457'), ('name', 'continental country')]
# [('s', 'http://www.wikidata.org/entity/Q1309121'), ('name', 'hermit kingdom')]
# [('s', 'http://www.wikidata.org/entity/Q1641089'), ('name', 'Multinational state')]
# 13

# %%
#return instances of country bordering the Baltic Sea
queryString = """
SELECT DISTINCT ?s ?name
WHERE {
   # ?s wdt:P31 wd:Q63791824.
   # get the label
   # ?s sc:name ?name.
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('s', 'http://www.wikidata.org/entity/Q183'), ('name', 'Germany')]
# [('s', 'http://www.wikidata.org/entity/Q211'), ('name', 'Latvia')]
# [('s', 'http://www.wikidata.org/entity/Q33'), ('name', 'Finland')]
# [('s', 'http://www.wikidata.org/entity/Q35'), ('name', 'Denmark')]
# 4

# %%
#return what country is instance of
queryString = """
SELECT DISTINCT ?o ?name
WHERE {
   wd:Q6256 wdt:P31 ?o.
   # get the label
   # ?o sc:name ?name.
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('o', 'http://www.wikidata.org/entity/Q104098715'), ('name', 'territorial entity type')]
# 1

# %%
#return superclass for country
queryString = """
SELECT DISTINCT ?o ?name
WHERE {
   wd:Q6256 wdt:P279 ?o.
   # get the label
   # ?o sc:name ?name.
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('o', 'http://www.wikidata.org/entity/Q1048835'), ('name', 'political territorial entity')]
# 1

# %%
# return nodes instance of country with link currency to Euro
queryString = """
SELECT DISTINCT ?s ?name
WHERE {
   # ?s wdt:P31 wd:Q6256;
      wdt:P38 wd:Q4916.
   # get the label
   # ?s sc:name ?name.
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('s', 'http://www.wikidata.org/entity/Q142'), ('name', 'France')]
# [('s', 'http://www.wikidata.org/entity/Q211'), ('name', 'Latvia')]
# [('s', 'http://www.wikidata.org/entity/Q214'), ('name', 'Slovakia')]
# [('s', 'http://www.wikidata.org/entity/Q228'), ('name', 'Andorra')]
# [('s', 'http://www.wikidata.org/entity/Q229'), ('name', 'Cyprus')]
# [('s', 'http://www.wikidata.org/entity/Q233'), ('name', 'Malta')]
# [('s', 'http://www.wikidata.org/entity/Q236'), ('name', 'Montenegro')]
# [('s', 'http://www.wikidata.org/entity/Q27'), ('name', 'Ireland')]
# [('s', 'http://www.wikidata.org/entity/Q29999'), ('name', 'Kingdom of the Netherlands')]
# [('s', 'http://www.wikidata.org/entity/Q33'), ('name', 'Finland')]
# [('s', 'http://www.wikidata.org/entity/Q38'), ('name', 'Italy')]
# [('s', 'http://www.wikidata.org/entity/Q40'), ('name', 'Austria')]
# [('s', 'http://www.wikidata.org/entity/Q41'), ('name', 'Greece')]
# [('s', 'http://www.wikidata.org/entity/Q45'), ('name', 'Portugal')]
# [('s', 'http://www.wikidata.org/entity/Q55'), ('name', 'Netherlands')]
# 15

# %%
#Return instances of country or sovereign state which currently use Euro
queryString = """
SELECT DISTINCT ?s ?name
WHERE {
   # ?s wdt:P31 ?class;
      wdt:P38 wd:Q4916.
   # get the label
   # ?s sc:name ?name.
   FILTER(?class IN (wd:Q6256, wd:Q3624078))
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('s', 'http://www.wikidata.org/entity/Q142'), ('name', 'France')]
# [('s', 'http://www.wikidata.org/entity/Q183'), ('name', 'Germany')]
# [('s', 'http://www.wikidata.org/entity/Q191'), ('name', 'Estonia')]
# [('s', 'http://www.wikidata.org/entity/Q211'), ('name', 'Latvia')]
# [('s', 'http://www.wikidata.org/entity/Q214'), ('name', 'Slovakia')]
# [('s', 'http://www.wikidata.org/entity/Q215'), ('name', 'Slovenia')]
# [('s', 'http://www.wikidata.org/entity/Q228'), ('name', 'Andorra')]
# [('s', 'http://www.wikidata.org/entity/Q229'), ('name', 'Cyprus')]
# [('s', 'http://www.wikidata.org/entity/Q233'), ('name', 'Malta')]
# [('s', 'http://www.wikidata.org/entity/Q235'), ('name', 'Monaco')]
# [('s', 'http://www.wikidata.org/entity/Q236'), ('name', 'Montenegro')]
# [('s', 'http://www.wikidata.org/entity/Q237'), ('name', 'Vatican City')]
# [('s', 'http://www.wikidata.org/entity/Q238'), ('name', 'San Marino')]
# [('s', 'http://www.wikidata.org/entity/Q27'), ('name', 'Ireland')]
# [('s', 'http://www.wikidata.org/entity/Q29'), ('name', 'Spain')]
# [('s', 'http://www.wikidata.org/entity/Q29999'), ('name', 'Kingdom of the Netherlands')]
# [('s', 'http://www.wikidata.org/entity/Q31'), ('name', 'Belgium')]
# [('s', 'http://www.wikidata.org/entity/Q32'), ('name', 'Luxembourg')]
# [('s', 'http://www.wikidata.org/entity/Q33'), ('name', 'Finland')]
# [('s', 'http://www.wikidata.org/entity/Q37'), ('name', 'Lithuania')]
# [('s', 'http://www.wikidata.org/entity/Q38'), ('name', 'Italy')]
# [('s', 'http://www.wikidata.org/entity/Q40'), ('name', 'Austria')]
# [('s', 'http://www.wikidata.org/entity/Q41'), ('name', 'Greece')]
# [('s', 'http://www.wikidata.org/entity/Q45'), ('name', 'Portugal')]
# [('s', 'http://www.wikidata.org/entity/Q55'), ('name', 'Netherlands')]
# 25

# %%
#Return instances of a subclass of country which currently use Euro
queryString = """
SELECT DISTINCT ?s ?name
WHERE {
   # ?s wdt:P31 ?class;
      wdt:P38 wd:Q4916.
   # ?class wdt:P279 wd:Q6256.
   # get the label
   # ?s sc:name ?name.
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('s', 'http://www.wikidata.org/entity/Q142'), ('name', 'France')]
# [('s', 'http://www.wikidata.org/entity/Q183'), ('name', 'Germany')]
# [('s', 'http://www.wikidata.org/entity/Q191'), ('name', 'Estonia')]
# [('s', 'http://www.wikidata.org/entity/Q211'), ('name', 'Latvia')]
# [('s', 'http://www.wikidata.org/entity/Q214'), ('name', 'Slovakia')]
# [('s', 'http://www.wikidata.org/entity/Q215'), ('name', 'Slovenia')]
# [('s', 'http://www.wikidata.org/entity/Q228'), ('name', 'Andorra')]
# [('s', 'http://www.wikidata.org/entity/Q229'), ('name', 'Cyprus')]
# [('s', 'http://www.wikidata.org/entity/Q233'), ('name', 'Malta')]
# [('s', 'http://www.wikidata.org/entity/Q235'), ('name', 'Monaco')]
# [('s', 'http://www.wikidata.org/entity/Q236'), ('name', 'Montenegro')]
# [('s', 'http://www.wikidata.org/entity/Q237'), ('name', 'Vatican City')]
# [('s', 'http://www.wikidata.org/entity/Q238'), ('name', 'San Marino')]
# [('s', 'http://www.wikidata.org/entity/Q27'), ('name', 'Ireland')]
# [('s', 'http://www.wikidata.org/entity/Q29'), ('name', 'Spain')]
# [('s', 'http://www.wikidata.org/entity/Q29999'), ('name', 'Kingdom of the Netherlands')]
# [('s', 'http://www.wikidata.org/entity/Q31'), ('name', 'Belgium')]
# [('s', 'http://www.wikidata.org/entity/Q32'), ('name', 'Luxembourg')]
# [('s', 'http://www.wikidata.org/entity/Q33'), ('name', 'Finland')]
# [('s', 'http://www.wikidata.org/entity/Q37'), ('name', 'Lithuania')]
# [('s', 'http://www.wikidata.org/entity/Q38'), ('name', 'Italy')]
# [('s', 'http://www.wikidata.org/entity/Q40'), ('name', 'Austria')]
# [('s', 'http://www.wikidata.org/entity/Q41'), ('name', 'Greece')]
# [('s', 'http://www.wikidata.org/entity/Q45'), ('name', 'Portugal')]
# 24

# %%
#Return subjects linked to Euro by currency property
queryString = """
SELECT DISTINCT ?s ?name
WHERE {
   # ?s wdt:P38 wd:Q4916.
   # get the label
   # ?s sc:name ?name.
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('s', 'http://www.wikidata.org/entity/Q1628531'), ('name', 'Quintanar de la Orden')]
# [('s', 'http://www.wikidata.org/entity/Q673727'), ('name', 'Neudau')]
# [('s', 'http://www.wikidata.org/entity/Q28124876'), ('name', 'Ilmspan')]
# [('s', 'http://www.wikidata.org/entity/Q11959'), ('name', 'Alicante')]
# [('s', 'http://www.wikidata.org/entity/Q25362'), ('name', 'Saint Barthélemy')]
# [('s', 'http://www.wikidata.org/entity/Q17054'), ('name', 'Martinique')]
# [('s', 'http://www.wikidata.org/entity/Q656699'), ('name', 'Montsoreau')]
# [('s', 'http://www.wikidata.org/entity/Q624511'), ('name', 'Aracena')]
# [('s', 'http://www.wikidata.org/entity/Q1246'), ('name', 'Kosovo')]
# [('s', 'http://www.wikidata.org/entity/Q126125'), ('name', 'Saint Martin (French part)')]
# [('s', 'http://www.wikidata.org/entity/Q129003'), ('name', 'French Southern and Antarctic Lands')]
# [('s', 'http://www.wikidata.org/entity/Q13116'), ('name', 'Benelux')]
# [('s', 'http://www.wikidata.org/entity/Q142'), ('name', 'France')]
# [('s', 'http://www.wikidata.org/entity/Q183'), ('name', 'Germany')]
# [('s', 'http://www.wikidata.org/entity/Q191'), ('name', 'Estonia')]
# [('s', 'http://www.wikidata.org/entity/Q1943433'), ('name', 'Molenwaard')]
# [('s', 'http://www.wikidata.org/entity/Q211'), ('name', 'Latvia')]
# [('s', 'http://www.wikidata.org/entity/Q212429'), ('name', 'Metropolitan France')]
# [('s', 'http://www.wikidata.org/entity/Q214'), ('name', 'Slovakia')]
# [('s', 'http://www.wikidata.org/entity/Q215'), ('name', 'Slovenia')]
# [('s', 'http://www.wikidata.org/entity/Q228'), ('name', 'Andorra')]
# [('s', 'http://www.wikidata.org/entity/Q229'), ('name', 'Cyprus')]
# [('s', 'http://www.wikidata.org/entity/Q233'), ('name', 'Malta')]
# [('s', 'http://www.wikidata.org/entity/Q235'), ('name', 'Monaco')]
# [('s', 'http://www.wikidata.org/entity/Q236'), ('name', 'Montenegro')]
# [('s', 'http://www.wikidata.org/entity/Q237'), ('name', 'Vatican City')]
# [('s', 'http://www.wikidata.org/entity/Q238'), ('name', 'San Marino')]
# [('s', 'http://www.wikidata.org/entity/Q25263'), ('name', 'Azores')]
# [('s', 'http://www.wikidata.org/entity/Q27'), ('name', 'Ireland')]
# [('s', 'http://www.wikidata.org/entity/Q29'), ('name', 'Spain')]
# [('s', 'http://www.wikidata.org/entity/Q29999'), ('name', 'Kingdom of the Netherlands')]
# [('s', 'http://www.wikidata.org/entity/Q31'), ('name', 'Belgium')]
# [('s', 'http://www.wikidata.org/entity/Q32'), ('name', 'Luxembourg')]
# [('s', 'http://www.wikidata.org/entity/Q33'), ('name', 'Finland')]
# [('s', 'http://www.wikidata.org/entity/Q37'), ('name', 'Lithuania')]
# [('s', 'http://www.wikidata.org/entity/Q3769'), ('name', 'French Guiana')]
# [('s', 'http://www.wikidata.org/entity/Q38'), ('name', 'Italy')]
# [('s', 'http://www.wikidata.org/entity/Q40'), ('name', 'Austria')]
# [('s', 'http://www.wikidata.org/entity/Q41'), ('name', 'Greece')]
# [('s', 'http://www.wikidata.org/entity/Q45'), ('name', 'Portugal')]
# [('s', 'http://www.wikidata.org/entity/Q458'), ('name', 'European Union')]
# [('s', 'http://www.wikidata.org/entity/Q55'), ('name', 'Netherlands')]
# [('s', 'http://www.wikidata.org/entity/Q5705'), ('name', 'Catalonia')]
# [('s', 'http://www.wikidata.org/entity/Q67585'), ('name', 'Münchringen')]
# [('s', 'http://www.wikidata.org/entity/Q720507'), ('name', 'economy of the European Union')]
# [('s', 'http://www.wikidata.org/entity/Q8062'), ('name', 'economy of the Republic of Ireland')]
# [('s', 'http://www.wikidata.org/entity/Q8268'), ('name', 'Eurozone')]
# [('s', 'http://www.wikidata.org/entity/Q869882'), ('name', 'Noyales')]
# [('s', 'http://www.wikidata.org/entity/Q12258'), ('name', 'Sabadell')]
# [('s', 'http://www.wikidata.org/entity/Q17012'), ('name', 'Guadeloupe')]
# [('s', 'http://www.wikidata.org/entity/Q17070'), ('name', 'Réunion')]
# [('s', 'http://www.wikidata.org/entity/Q5689'), ('name', 'Åland')]
# [('s', 'http://www.wikidata.org/entity/Q936563'), ('name', 'Italian Bourse')]
# [('s', 'http://www.wikidata.org/entity/Q649612'), ('name', 'Coca')]
# [('s', 'http://www.wikidata.org/entity/Q1150680'), ('name', 'Republic of Montenegro')]
# [('s', 'http://www.wikidata.org/entity/Q4513926'), ('name', 'Montenegro Stock Exchange')]
# [('s', 'http://www.wikidata.org/entity/Q1771153'), ('name', 'Albuixech')]
# [('s', 'http://www.wikidata.org/entity/Q4502305'), ('name', 'Huma')]
# [('s', 'http://www.wikidata.org/entity/Q17063'), ('name', 'Mayotte')]
# [('s', 'http://www.wikidata.org/entity/Q37024'), ('name', 'Serbia and Montenegro')]
# [('s', 'http://www.wikidata.org/entity/Q34617'), ('name', 'Saint Pierre and Miquelon')]
# [('s', 'http://www.wikidata.org/entity/Q2982948'), ('name', 'European Collectivity of Alsace')]
# [('s', 'http://www.wikidata.org/entity/Q755341'), ('name', 'Athens Exchange')]
# [('s', 'http://www.wikidata.org/entity/Q686790'), ('name', 'Mediona')]
# [('s', 'http://www.wikidata.org/entity/Q1444150'), ('name', 'Alboloduy')]
# [('s', 'http://www.wikidata.org/entity/Q917883'), ('name', 'Molina de Segura')]
# [('s', 'http://www.wikidata.org/entity/Q1726029'), ('name', 'canton of Lézardrieux')]
# [('s', 'http://www.wikidata.org/entity/Q1631311'), ('name', 'Cuéllar')]
# [('s', 'http://www.wikidata.org/entity/Q1769772'), ('name', 'Bierge / Biarche')]
# [('s', 'http://www.wikidata.org/entity/Q628991'), ('name', 'Tamariz de Campos')]
# [('s', 'http://www.wikidata.org/entity/Q3777251'), ('name', 'Leap card')]
# [('s', 'http://www.wikidata.org/entity/Q112558'), ('name', 'Republic of Saugeais')]
# [('s', 'http://www.wikidata.org/entity/Q34234153'), ('name', 'Liberapay')]
# [('s', 'http://www.wikidata.org/entity/Q8050'), ('name', 'economy of Spain')]
# [('s', 'http://www.wikidata.org/entity/Q8057'), ('name', 'economy of France')]
# [('s', 'http://www.wikidata.org/entity/Q28124877'), ('name', 'Schönfeld')]
# [('s', 'http://www.wikidata.org/entity/Q61928556'), ('name', 'Rauenberg')]
# [('s', 'http://www.wikidata.org/entity/Q28124875'), ('name', 'Gerchsheim')]
# [('s', 'http://www.wikidata.org/entity/Q8085'), ('name', 'economy of Austria')]
# [('s', 'http://www.wikidata.org/entity/Q7942521'), ('name', 'Voyvodovo, Haskovo Province')]
# [('s', 'http://www.wikidata.org/entity/Q138837'), ('name', 'Catalan Republic')]
# [('s', 'http://www.wikidata.org/entity/Q190571'), ('name', 'Scattered Islands in the Indian Ocean')]
# [('s', 'http://www.wikidata.org/entity/Q1644430'), ('name', 'Monreal del Campo')]
# [('s', 'http://www.wikidata.org/entity/Q39486975'), ('name', 'EUR/USD')]
# [('s', 'http://www.wikidata.org/entity/Q39486982'), ('name', 'EUR/JPY')]
# [('s', 'http://www.wikidata.org/entity/Q1026524'), ('name', 'Hivange')]
# [('s', 'http://www.wikidata.org/entity/Q1299355'), ('name', 'economy of Slovenia')]
# [('s', 'http://www.wikidata.org/entity/Q9031607'), ('name', 'BME Growth')]
# [('s', 'http://www.wikidata.org/entity/Q73330139'), ('name', 'Verdis')]
# [('s', 'http://www.wikidata.org/entity/Q98834701'), ('name', 'Adriatic Bank')]
# [('s', 'http://www.wikidata.org/entity/Q39486984'), ('name', 'EUR/GBP')]
# [('s', 'http://www.wikidata.org/entity/Q1423680'), ('name', 'Gay and Lesbian Kingdom of the Coral Sea Islands')]
# 92

# %%
#Return the countries which currently use Euro filter country instance of country or sovereign state
queryString = """
SELECT DISTINCT ?s ?name
WHERE {
   # ?s wdt:P31 ?class;
      wdt:P38 wd:Q4916.
   # get the label
   # ?s sc:name ?name.
   FILTER(?class IN (wd:Q6256, wd:Q3624078))
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('s', 'http://www.wikidata.org/entity/Q142'), ('name', 'France')]
# [('s', 'http://www.wikidata.org/entity/Q183'), ('name', 'Germany')]
# [('s', 'http://www.wikidata.org/entity/Q191'), ('name', 'Estonia')]
# [('s', 'http://www.wikidata.org/entity/Q211'), ('name', 'Latvia')]
# [('s', 'http://www.wikidata.org/entity/Q214'), ('name', 'Slovakia')]
# [('s', 'http://www.wikidata.org/entity/Q215'), ('name', 'Slovenia')]
# [('s', 'http://www.wikidata.org/entity/Q228'), ('name', 'Andorra')]
# [('s', 'http://www.wikidata.org/entity/Q229'), ('name', 'Cyprus')]
# [('s', 'http://www.wikidata.org/entity/Q233'), ('name', 'Malta')]
# [('s', 'http://www.wikidata.org/entity/Q235'), ('name', 'Monaco')]
# [('s', 'http://www.wikidata.org/entity/Q236'), ('name', 'Montenegro')]
# [('s', 'http://www.wikidata.org/entity/Q237'), ('name', 'Vatican City')]
# [('s', 'http://www.wikidata.org/entity/Q238'), ('name', 'San Marino')]
# [('s', 'http://www.wikidata.org/entity/Q27'), ('name', 'Ireland')]
# [('s', 'http://www.wikidata.org/entity/Q29'), ('name', 'Spain')]
# [('s', 'http://www.wikidata.org/entity/Q29999'), ('name', 'Kingdom of the Netherlands')]
# [('s', 'http://www.wikidata.org/entity/Q31'), ('name', 'Belgium')]
# [('s', 'http://www.wikidata.org/entity/Q32'), ('name', 'Luxembourg')]
# [('s', 'http://www.wikidata.org/entity/Q33'), ('name', 'Finland')]
# [('s', 'http://www.wikidata.org/entity/Q37'), ('name', 'Lithuania')]
# [('s', 'http://www.wikidata.org/entity/Q38'), ('name', 'Italy')]
# [('s', 'http://www.wikidata.org/entity/Q40'), ('name', 'Austria')]
# [('s', 'http://www.wikidata.org/entity/Q41'), ('name', 'Greece')]
# [('s', 'http://www.wikidata.org/entity/Q45'), ('name', 'Portugal')]
# [('s', 'http://www.wikidata.org/entity/Q55'), ('name', 'Netherlands')]
# 25

# %%
#Return the countries which currently use Euro with * operator
queryString = """
SELECT DISTINCT ?s ?name
WHERE {
   # ?s wdt:P31 ?class;
      wdt:P38 wd:Q4916.
   # ?class wdt:P279* wd:Q6256.
   # get the label
   # ?s sc:name ?name.
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('s', 'http://www.wikidata.org/entity/Q142'), ('name', 'France')]
# [('s', 'http://www.wikidata.org/entity/Q183'), ('name', 'Germany')]
# [('s', 'http://www.wikidata.org/entity/Q191'), ('name', 'Estonia')]
# [('s', 'http://www.wikidata.org/entity/Q211'), ('name', 'Latvia')]
# [('s', 'http://www.wikidata.org/entity/Q214'), ('name', 'Slovakia')]
# [('s', 'http://www.wikidata.org/entity/Q215'), ('name', 'Slovenia')]
# [('s', 'http://www.wikidata.org/entity/Q228'), ('name', 'Andorra')]
# [('s', 'http://www.wikidata.org/entity/Q229'), ('name', 'Cyprus')]
# [('s', 'http://www.wikidata.org/entity/Q233'), ('name', 'Malta')]
# [('s', 'http://www.wikidata.org/entity/Q235'), ('name', 'Monaco')]
# [('s', 'http://www.wikidata.org/entity/Q236'), ('name', 'Montenegro')]
# [('s', 'http://www.wikidata.org/entity/Q237'), ('name', 'Vatican City')]
# [('s', 'http://www.wikidata.org/entity/Q238'), ('name', 'San Marino')]
# [('s', 'http://www.wikidata.org/entity/Q27'), ('name', 'Ireland')]
# [('s', 'http://www.wikidata.org/entity/Q29'), ('name', 'Spain')]
# [('s', 'http://www.wikidata.org/entity/Q29999'), ('name', 'Kingdom of the Netherlands')]
# [('s', 'http://www.wikidata.org/entity/Q31'), ('name', 'Belgium')]
# [('s', 'http://www.wikidata.org/entity/Q32'), ('name', 'Luxembourg')]
# [('s', 'http://www.wikidata.org/entity/Q33'), ('name', 'Finland')]
# [('s', 'http://www.wikidata.org/entity/Q37'), ('name', 'Lithuania')]
# [('s', 'http://www.wikidata.org/entity/Q38'), ('name', 'Italy')]
# [('s', 'http://www.wikidata.org/entity/Q40'), ('name', 'Austria')]
# [('s', 'http://www.wikidata.org/entity/Q41'), ('name', 'Greece')]
# [('s', 'http://www.wikidata.org/entity/Q45'), ('name', 'Portugal')]
# [('s', 'http://www.wikidata.org/entity/Q55'), ('name', 'Netherlands')]
# 25

# %%
#Return the countries which currently use Euro with + operator
queryString = """
SELECT DISTINCT ?s ?name
WHERE {
   # ?s wdt:P31 ?class;
      wdt:P38 wd:Q4916.
   # ?class wdt:P279+ wd:Q6256.
   # get the label
   # ?s sc:name ?name.
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('s', 'http://www.wikidata.org/entity/Q142'), ('name', 'France')]
# [('s', 'http://www.wikidata.org/entity/Q183'), ('name', 'Germany')]
# [('s', 'http://www.wikidata.org/entity/Q191'), ('name', 'Estonia')]
# [('s', 'http://www.wikidata.org/entity/Q211'), ('name', 'Latvia')]
# [('s', 'http://www.wikidata.org/entity/Q214'), ('name', 'Slovakia')]
# [('s', 'http://www.wikidata.org/entity/Q215'), ('name', 'Slovenia')]
# [('s', 'http://www.wikidata.org/entity/Q228'), ('name', 'Andorra')]
# [('s', 'http://www.wikidata.org/entity/Q229'), ('name', 'Cyprus')]
# [('s', 'http://www.wikidata.org/entity/Q233'), ('name', 'Malta')]
# [('s', 'http://www.wikidata.org/entity/Q235'), ('name', 'Monaco')]
# [('s', 'http://www.wikidata.org/entity/Q236'), ('name', 'Montenegro')]
# [('s', 'http://www.wikidata.org/entity/Q237'), ('name', 'Vatican City')]
# [('s', 'http://www.wikidata.org/entity/Q238'), ('name', 'San Marino')]
# [('s', 'http://www.wikidata.org/entity/Q27'), ('name', 'Ireland')]
# [('s', 'http://www.wikidata.org/entity/Q29'), ('name', 'Spain')]
# [('s', 'http://www.wikidata.org/entity/Q29999'), ('name', 'Kingdom of the Netherlands')]
# [('s', 'http://www.wikidata.org/entity/Q31'), ('name', 'Belgium')]
# [('s', 'http://www.wikidata.org/entity/Q32'), ('name', 'Luxembourg')]
# [('s', 'http://www.wikidata.org/entity/Q33'), ('name', 'Finland')]
# [('s', 'http://www.wikidata.org/entity/Q37'), ('name', 'Lithuania')]
# [('s', 'http://www.wikidata.org/entity/Q38'), ('name', 'Italy')]
# [('s', 'http://www.wikidata.org/entity/Q40'), ('name', 'Austria')]
# [('s', 'http://www.wikidata.org/entity/Q41'), ('name', 'Greece')]
# [('s', 'http://www.wikidata.org/entity/Q45'), ('name', 'Portugal')]
# 24

# %% [markdown]
# Final query for this task

# %%
# write your final query
queryString = """
SELECT DISTINCT ?s ?name
WHERE {
   # ?s wdt:P31/wdt:P279* wd:Q6256;
      wdt:P38 wd:Q4916.

   # ?s sc:name ?name.
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('s', 'http://www.wikidata.org/entity/Q142'), ('name', 'France')]
# [('s', 'http://www.wikidata.org/entity/Q183'), ('name', 'Germany')]
# [('s', 'http://www.wikidata.org/entity/Q191'), ('name', 'Estonia')]
# [('s', 'http://www.wikidata.org/entity/Q211'), ('name', 'Latvia')]
# [('s', 'http://www.wikidata.org/entity/Q214'), ('name', 'Slovakia')]
# [('s', 'http://www.wikidata.org/entity/Q215'), ('name', 'Slovenia')]
# [('s', 'http://www.wikidata.org/entity/Q228'), ('name', 'Andorra')]
# [('s', 'http://www.wikidata.org/entity/Q229'), ('name', 'Cyprus')]
# [('s', 'http://www.wikidata.org/entity/Q233'), ('name', 'Malta')]
# [('s', 'http://www.wikidata.org/entity/Q235'), ('name', 'Monaco')]
# [('s', 'http://www.wikidata.org/entity/Q236'), ('name', 'Montenegro')]
# [('s', 'http://www.wikidata.org/entity/Q237'), ('name', 'Vatican City')]
# [('s', 'http://www.wikidata.org/entity/Q238'), ('name', 'San Marino')]
# [('s', 'http://www.wikidata.org/entity/Q27'), ('name', 'Ireland')]
# [('s', 'http://www.wikidata.org/entity/Q29'), ('name', 'Spain')]
# [('s', 'http://www.wikidata.org/entity/Q29999'), ('name', 'Kingdom of the Netherlands')]
# [('s', 'http://www.wikidata.org/entity/Q31'), ('name', 'Belgium')]
# [('s', 'http://www.wikidata.org/entity/Q32'), ('name', 'Luxembourg')]
# [('s', 'http://www.wikidata.org/entity/Q33'), ('name', 'Finland')]
# [('s', 'http://www.wikidata.org/entity/Q37'), ('name', 'Lithuania')]
# [('s', 'http://www.wikidata.org/entity/Q38'), ('name', 'Italy')]
# [('s', 'http://www.wikidata.org/entity/Q40'), ('name', 'Austria')]
# [('s', 'http://www.wikidata.org/entity/Q41'), ('name', 'Greece')]
# [('s', 'http://www.wikidata.org/entity/Q45'), ('name', 'Portugal')]
# [('s', 'http://www.wikidata.org/entity/Q55'), ('name', 'Netherlands')]
# 25

# %% [markdown]
# ## Task 3
# Return the countries belonging to the European Union, with a currency different from the Euro (return also their currency).

# %%
# return what Italy is member of (wrong variable)
queryString = """
SELECT DISTINCT ?o ?name
WHERE {
   wd:Q38 wdt:P463 ?o.
   # get the label
   # ?p sc:name ?name.
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('o', 'http://www.wikidata.org/entity/Q488981'), ('name', 'software version identifier')]
# [('o', 'http://www.wikidata.org/entity/Q488981'), ('name', 'tabular software version')]
# [('o', 'http://www.wikidata.org/entity/Q488981'), ('name', 'has edition or translation')]
# [('o', 'http://www.wikidata.org/entity/Q488981'), ('name', 'Fonsi Nieto')]
# [('o', 'http://www.wikidata.org/entity/Q488981'), ('name', "Al Stewart's albums in chronological order")]
# [('o', 'http://www.wikidata.org/entity/Q488981'), ('name', 'Category:Adelina Lopes Vieira')]
# [('o', 'http://www.wikidata.org/entity/Q488981'), ('name', 'Lubomír Stoklásek')]
# [('o', 'http://www.wikidata.org/entity/Q488981'), ('name', 'Ciudad Vieja')]
# [('o', 'http://www.wikidata.org/entity/Q488981'), ('name', 'Echániz')]
# [('o', 'http://www.wikidata.org/entity/Q488981'), ('name', 'Natuna')]
# [('o', 'http://www.wikidata.org/entity/Q488981'), ('name', "Acid Mothers Temple's albums in chronological order")]
# [('o', 'http://www.wikidata.org/entity/Q488981'), ('name', 'Relaño')]
# [('o', 'http://www.wikidata.org/entity/Q488981'), ('name', '2002 in transport')]
# [('o', 'http://www.wikidata.org/entity/Q488981'), ('name', '2006 in transport')]
# [('o', 'http://www.wikidata.org/entity/Q488981'), ('name', 'Category:1920 elections in Oceania')]
# [('o', 'http://www.wikidata.org/entity/Q488981'), ('name', 'Category:2002 elections in South America')]
# [('o', 'http://www.wikidata.org/entity/Q488981'), ('name', 'Category:Teluk Sebong')]
# [('o', 'http://www.wikidata.org/entity/Q488981'), ('name', 'Võnnu Rural Municipality')]
# [('o', 'http://www.wikidata.org/entity/Q488981'), ('name', 'Kojiro Kobayashi')]
# [('o', 'http://www.wikidata.org/entity/Q488981'), ('name', 'Miguel E. M. Herrera')]
# [('o', 'http://www.wikidata.org/entity/Q488981'), ('name', 'Category:Akita Shoten magazines')]
# [('o', 'http://www.wikidata.org/entity/Q488981'), ('name', "2010 CONCACAF Women's Gold Cup")]
# [('o', 'http://www.wikidata.org/entity/Q488981'), ('name', '2014 FIFA World Cup venues')]
# [('o', 'http://www.wikidata.org/entity/Q488981'), ('name', 'ambassador of Guatemala to France')]
# [('o', 'http://www.wikidata.org/entity/Q488981'), ('name', 'Estação Ferroviária de Mafra')]
# [('o', 'http://www.wikidata.org/entity/Q488981'), ('name', 'Faculdade de Letras da Universidade de Coimbra')]
# [('o', 'http://www.wikidata.org/entity/Q488981'), ('name', 'Faculty of Arts and Humanities of the University of Porto')]
# [('o', 'http://www.wikidata.org/entity/Q488981'), ('name', 'Aji')]
# [('o', 'http://www.wikidata.org/entity/Q488981'), ('name', 'Urucu')]
# [('o', 'http://www.wikidata.org/entity/Q488981'), ('name', 'jikimiyake')]
# [('o', 'http://www.wikidata.org/entity/Q488981'), ('name', 'war horse')]
# [('o', 'http://www.wikidata.org/entity/Q488981'), ('name', '2010 Pacific hurricane season')]
# [('o', 'http://www.wikidata.org/entity/Q488981'), ('name', '1972 in economics')]
# [('o', 'http://www.wikidata.org/entity/Q488981'), ('name', '2020 Winter Youth Olympics')]
# [('o', 'http://www.wikidata.org/entity/Q488981'), ('name', 'Hitachi Province')]
# [('o', 'http://www.wikidata.org/entity/Q488981'), ('name', 'Lightiella')]
# [('o', 'http://www.wikidata.org/entity/Q488981'), ('name', 'compilation album released this year')]
# [('o', 'http://www.wikidata.org/entity/Q488981'), ('name', 'region of Ethiopia')]
# [('o', 'http://www.wikidata.org/entity/Q488981'), ('name', 'Mateo Egea')]
# [('o', 'http://www.wikidata.org/entity/Q488981'), ('name', '1942 in meteorology')]
# [('o', 'http://www.wikidata.org/entity/Q488981'), ('name', '1958 in meteorology')]
# [('o', 'http://www.wikidata.org/entity/Q488981'), ('name', '1964 in meteorology')]
# [('o', 'http://www.wikidata.org/entity/Q488981'), ('name', '1971 in meteorology')]
# [('o', 'http://www.wikidata.org/entity/Q488981'), ('name', '1989 in meteorology')]
# [('o', 'http://www.wikidata.org/entity/Q488981'), ('name', '2000 in meteorology')]
# [('o', 'http://www.wikidata.org/entity/Q488981'), ('name', '2003 in meteorology')]
# [('o', 'http://www.wikidata.org/entity/Q488981'), ('name', 'Nemėžis')]
# [('o', 'http://www.wikidata.org/entity/Q488981'), ('name', '530 BC')]
# [('o', 'http://www.wikidata.org/entity/Q488981'), ('name', 'ambassador of China to Peru')]
# [('o', 'http://www.wikidata.org/entity/Q488981'), ('name', 'Pleomothra')]
# [('o', 'http://www.wikidata.org/entity/Q488981'), ('name', '1967 in politics')]
# [('o', 'http://www.wikidata.org/entity/Q488981'), ('name', '1970 FIFA World Cup qualification')]
# [('o', 'http://www.wikidata.org/entity/Q488981'), ('name', 'List of ambassadors of Gabon to the United States')]
# [('o', 'http://www.wikidata.org/entity/Q488981'), ('name', 'Vietnamese name')]
# [('o', 'http://www.wikidata.org/entity/Q488981'), ('name', '2003 in the Democratic Republic of the Congo')]
# [('o', 'http://www.wikidata.org/entity/Q488981'), ('name', '2000 in the Democratic Republic of the Congo')]
# [('o', 'http://www.wikidata.org/entity/Q488981'), ('name', 'List of ANZ Championship players')]
# [('o', 'http://www.wikidata.org/entity/Q488981'), ('name', 'veterinary scientist')]
# [('o', 'http://www.wikidata.org/entity/Q488981'), ('name', 'Suctobelbella')]
# [('o', 'http://www.wikidata.org/entity/Q488981'), ('name', 'Versailles EPs discography')]
# [('o', 'http://www.wikidata.org/entity/Q488981'), ('name', '2014 in Namibia')]
# [('o', 'http://www.wikidata.org/entity/Q488981'), ('name', '1975 in sports')]
# [('o', 'http://www.wikidata.org/entity/Q488981'), ('name', "Aaliyah's albums in chronological order")]
# [('o', 'http://www.wikidata.org/entity/Q488981'), ('name', 'Jerónimo Latorre')]
# [('o', 'http://www.wikidata.org/entity/Q488981'), ('name', '2000 in Uganda')]
# [('o', 'http://www.wikidata.org/entity/Q488981'), ('name', 'Paratge natural municipal')]
# [('o', 'http://www.wikidata.org/entity/Q488981'), ('name', '1972 in sports')]
# [('o', 'http://www.wikidata.org/entity/Q488981'), ('name', 'Alma Scots baseball')]
# [('o', 'http://www.wikidata.org/entity/Q488981'), ('name', 'Alfred Saxons football')]
# [('o', 'http://www.wikidata.org/entity/Q488981'), ('name', '1987 in sports')]
# [('o', 'http://www.wikidata.org/entity/Q488981'), ('name', '1928 in sports')]
# [('o', 'http://www.wikidata.org/entity/Q488981'), ('name', '2010 World Touring Car Championship season')]
# [('o', 'http://www.wikidata.org/entity/Q488981'), ('name', '2004 UEFA European Under-17 Football Championship')]
# [('o', 'http://www.wikidata.org/entity/Q488981'), ('name', '2012 in Vietnam')]
# [('o', 'http://www.wikidata.org/entity/Q488981'), ('name', '1984 in Taiwan')]
# [('o', 'http://www.wikidata.org/entity/Q488981'), ('name', 'Green Garden Pop')]
# [('o', 'http://www.wikidata.org/entity/Q488981'), ('name', 'Kakyuusei 2')]
# [('o', 'http://www.wikidata.org/entity/Q488981'), ('name', 'List of ambassador of China to Peru')]
# [('o', 'http://www.wikidata.org/entity/Q488981'), ('name', '1994 in sports')]
# [('o', 'http://www.wikidata.org/entity/Q488981'), ('name', 'tidal locking')]
# [('o', 'http://www.wikidata.org/entity/Q488981'), ('name', '1998 in sports')]
# [('o', 'http://www.wikidata.org/entity/Q488981'), ('name', 'Aegadian Islands')]
# [('o', 'http://www.wikidata.org/entity/Q488981'), ('name', 'Vice President of the Maldives')]
# [('o', 'http://www.wikidata.org/entity/Q488981'), ('name', 'Prince Qing')]
# [('o', 'http://www.wikidata.org/entity/Q488981'), ('name', "Grey's Anatomy, season 1")]
# [('o', 'http://www.wikidata.org/entity/Q488981'), ('name', 'Category:2009 in Australian sport')]
# [('o', 'http://www.wikidata.org/entity/Q488981'), ('name', '1990 in volleyball')]
# [('o', 'http://www.wikidata.org/entity/Q488981'), ('name', '1998 in education')]
# [('o', 'http://www.wikidata.org/entity/Q488981'), ('name', '2016 in transport')]
# [('o', 'http://www.wikidata.org/entity/Q488981'), ('name', '1995 UCI Track Cycling World Championships')]
# [('o', 'http://www.wikidata.org/entity/Q488981'), ('name', 'Tokyo Solamachi')]
# [('o', 'http://www.wikidata.org/entity/Q488981'), ('name', 'Kubuntu')]
# [('o', 'http://www.wikidata.org/entity/Q488981'), ('name', 'The Village Gate')]
# [('o', 'http://www.wikidata.org/entity/Q488981'), ('name', 'Orix Real Estate')]
# [('o', 'http://www.wikidata.org/entity/Q488981'), ('name', "All People's Party")]
# [('o', 'http://www.wikidata.org/entity/Q488981'), ('name', 'Sliven Province')]
# [('o', 'http://www.wikidata.org/entity/Q488981'), ('name', 'list of Vegalta Sendai players')]
# [('o', 'http://www.wikidata.org/entity/Q488981'), ('name', 'Shimo-Umi Station')]
# [('o', 'http://www.wikidata.org/entity/Q488981'), ('name', '2009–2010 Coupe de France')]
# [('o', 'http://www.wikidata.org/entity/Q488981'), ('name', 'Bingo-nada')]
# 100

# %%
# return what Italy is part of
queryString = """
SELECT DISTINCT ?o ?name
WHERE {
   wd:Q38 wdt:P361 ?o.
   # get the label
   # ?o sc:name ?name.
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('o', 'http://www.wikidata.org/entity/Q46'), ('name', 'Europe')]
# 1

# %%
# return property for Europe
queryString = """
SELECT DISTINCT ?p ?name
WHERE {
   wd:Q46 ?p ?o.
   # get the label
   # ?p sc:name ?name.
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P7607'), ('name', 'WikiTree category or space')]
# [('p', 'http://www.wikidata.org/prop/direct/P1036'), ('name', 'Dewey Decimal Classification')]
# [('p', 'http://www.wikidata.org/prop/direct/P1082'), ('name', 'population')]
# [('p', 'http://www.wikidata.org/prop/direct/P1151'), ('name', "topic's main Wikimedia portal")]
# [('p', 'http://www.wikidata.org/prop/direct/P1225'), ('name', 'U.S. National Archives Identifier')]
# [('p', 'http://www.wikidata.org/prop/direct/P1245'), ('name', 'OmegaWiki Defined Meaning')]
# [('p', 'http://www.wikidata.org/prop/direct/P1281'), ('name', 'WOEID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1296'), ('name', 'Gran Enciclopèdia Catalana ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1343'), ('name', 'described by source')]
# [('p', 'http://www.wikidata.org/prop/direct/P138'), ('name', 'named after')]
# [('p', 'http://www.wikidata.org/prop/direct/P1417'), ('name', 'Encyclopædia Britannica Online ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1424'), ('name', "topic's main template")]
# [('p', 'http://www.wikidata.org/prop/direct/P1449'), ('name', 'nickname')]
# [('p', 'http://www.wikidata.org/prop/direct/P1464'), ('name', 'category for people born here')]
# [('p', 'http://www.wikidata.org/prop/direct/P1465'), ('name', 'category for people who died here')]
# [('p', 'http://www.wikidata.org/prop/direct/P1482'), ('name', 'Stack Exchange tag')]
# [('p', 'http://www.wikidata.org/prop/direct/P1549'), ('name', 'demonym')]
# [('p', 'http://www.wikidata.org/prop/direct/P1566'), ('name', 'GeoNames ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1584'), ('name', 'Pleiades ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1621'), ('name', 'detail map')]
# [('p', 'http://www.wikidata.org/prop/direct/P163'), ('name', 'flag')]
# [('p', 'http://www.wikidata.org/prop/direct/P1667'), ('name', 'Getty Thesaurus of Geographic Names ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1740'), ('name', 'category for films shot at this location')]
# [('p', 'http://www.wikidata.org/prop/direct/P1791'), ('name', 'category of people buried here')]
# [('p', 'http://www.wikidata.org/prop/direct/P18'), ('name', 'image')]
# [('p', 'http://www.wikidata.org/prop/direct/P1889'), ('name', 'different from')]
# [('p', 'http://www.wikidata.org/prop/direct/P1943'), ('name', 'location map')]
# [('p', 'http://www.wikidata.org/prop/direct/P1944'), ('name', 'relief location map')]
# [('p', 'http://www.wikidata.org/prop/direct/P1968'), ('name', 'Foursquare venue ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2046'), ('name', 'area')]
# [('p', 'http://www.wikidata.org/prop/direct/P2082'), ('name', 'M.49 code')]
# [('p', 'http://www.wikidata.org/prop/direct/P214'), ('name', 'VIAF ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2163'), ('name', 'FAST ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2184'), ('name', 'history of topic')]
# [('p', 'http://www.wikidata.org/prop/direct/P227'), ('name', 'GND ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2347'), ('name', 'YSO ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P242'), ('name', 'locator map image')]
# [('p', 'http://www.wikidata.org/prop/direct/P244'), ('name', 'Library of Congress authority ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2573'), ('name', 'number of out-of-school children')]
# [('p', 'http://www.wikidata.org/prop/direct/P2579'), ('name', 'studied by')]
# [('p', 'http://www.wikidata.org/prop/direct/P2581'), ('name', 'BabelNet ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2612'), ('name', 'TED topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2633'), ('name', 'geography of topic')]
# [('p', 'http://www.wikidata.org/prop/direct/P2888'), ('name', 'exact match')]
# [('p', 'http://www.wikidata.org/prop/direct/P2924'), ('name', 'Great Russian Encyclopedia Online ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2950'), ('name', 'Nomisma ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2959'), ('name', 'permanent duplicated item')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('name', 'instance of')]
# [('p', 'http://www.wikidata.org/prop/direct/P3106'), ('name', 'Guardian topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3134'), ('name', 'TripAdvisor ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3221'), ('name', 'New York Times topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3222'), ('name', 'NE.se ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3241'), ('name', 'Catholic Encyclopedia ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3417'), ('name', 'Quora topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3479'), ('name', 'Omni topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P349'), ('name', 'National Diet Library ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3553'), ('name', 'Zhihu topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P361'), ('name', 'part of')]
# [('p', 'http://www.wikidata.org/prop/direct/P3612'), ('name', 'Le Monde diplomatique subject ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P373'), ('name', 'Commons category')]
# [('p', 'http://www.wikidata.org/prop/direct/P3847'), ('name', 'Open Library subject ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3911'), ('name', 'STW Thesaurus for Economics ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3916'), ('name', 'UNESCO Thesaurus ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3984'), ('name', 'subreddit')]
# [('p', 'http://www.wikidata.org/prop/direct/P4161'), ('name', 'Michelin Voyages ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P421'), ('name', 'located in time zone')]
# [('p', 'http://www.wikidata.org/prop/direct/P4342'), ('name', 'Store norske leksikon ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P4427'), ('name', 'GACS ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P443'), ('name', 'pronunciation audio')]
# [('p', 'http://www.wikidata.org/prop/direct/P4527'), ('name', 'UK Parliament thesaurus ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P460'), ('name', 'said to be the same as')]
# [('p', 'http://www.wikidata.org/prop/direct/P4613'), ('name', 'Encyclopedia of Modern Ukraine ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P47'), ('name', 'shares border with')]
# [('p', 'http://www.wikidata.org/prop/direct/P486'), ('name', 'MeSH descriptor ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P4973'), ('name', 'Wikitribune category')]
# [('p', 'http://www.wikidata.org/prop/direct/P5008'), ('name', 'on focus list of Wikimedia project')]
# [('p', 'http://www.wikidata.org/prop/direct/P5019'), ('name', 'Brockhaus Enzyklopädie online ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5063'), ('name', 'Interlingual Index ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5125'), ('name', 'Wikimedia outline')]
# [('p', 'http://www.wikidata.org/prop/direct/P5198'), ('name', 'ASC Leiden Thesaurus ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5247'), ('name', 'Giant Bomb ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5250'), ('name', 'IAB code')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('name', 'has part')]
# [('p', 'http://www.wikidata.org/prop/direct/P5437'), ('name', 'EuroVoc ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5573'), ('name', 'archINFORM location ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5587'), ('name', 'Libris-URI')]
# [('p', 'http://www.wikidata.org/prop/direct/P5748'), ('name', 'Basisklassifikation')]
# [('p', 'http://www.wikidata.org/prop/direct/P5905'), ('name', 'Comic Vine ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6058'), ('name', 'Larousse ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P610'), ('name', 'highest point')]
# [('p', 'http://www.wikidata.org/prop/direct/P6404'), ('name', "Treccani's Dizionario di Storia ID")]
# [('p', 'http://www.wikidata.org/prop/direct/P646'), ('name', 'Freebase ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6573'), ('name', 'Klexikon article ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6591'), ('name', 'maximum temperature record')]
# [('p', 'http://www.wikidata.org/prop/direct/P6766'), ('name', "Who's on First ID")]
# [('p', 'http://www.wikidata.org/prop/direct/P6839'), ('name', 'TV Tropes identifier')]
# [('p', 'http://www.wikidata.org/prop/direct/P6900'), ('name', 'NicoNicoPedia ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P691'), ('name', 'NKCR AUT ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7033'), ('name', 'Australian Educational Vocabulary ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P706'), ('name', 'located in/on physical feature')]
# 100

# %%
# return what is different from Europe
queryString = """
SELECT DISTINCT ?o ?name
WHERE {
   wd:Q46 wdt:P1889 ?o.
   # get the label
   # ?o sc:name ?name.
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('o', 'http://www.wikidata.org/entity/Q345567'), ('name', 'Europe')]
# [('o', 'http://www.wikidata.org/entity/Q741380'), ('name', 'Europa')]
# 2

# %%
# return what Itlay is part of
queryString = """
SELECT DISTINCT ?o ?name
WHERE {
   wd:Q38 wdt:P361 ?o.
   # get the label
   # ?o sc:name ?name.
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('o', 'http://www.wikidata.org/entity/Q46'), ('name', 'Europe')]
# 1

# %%
# return what Itlay is member of
queryString = """
SELECT DISTINCT ?o ?name
WHERE {
   wd:Q38 wdt:P463 ?o.
   # get the label
   # ?o sc:name ?name.
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('o', 'http://www.wikidata.org/entity/Q488981'), ('name', 'European Bank for Reconstruction and Development')]
# [('o', 'http://www.wikidata.org/entity/Q1153087'), ('name', 'Inter-American Development Bank')]
# [('o', 'http://www.wikidata.org/entity/Q848633'), ('name', 'International Chamber of Commerce')]
# [('o', 'http://www.wikidata.org/entity/Q1043527'), ('name', 'Multilateral Investment Guarantee Agency')]
# [('o', 'http://www.wikidata.org/entity/Q1065'), ('name', 'United Nations')]
# [('o', 'http://www.wikidata.org/entity/Q1072120'), ('name', 'Missile Technology Control Regime')]
# [('o', 'http://www.wikidata.org/entity/Q123209'), ('name', 'Latin Union')]
# [('o', 'http://www.wikidata.org/entity/Q125761'), ('name', 'International Civil Aviation Organization')]
# [('o', 'http://www.wikidata.org/entity/Q1377612'), ('name', 'European Payments Union')]
# [('o', 'http://www.wikidata.org/entity/Q141720'), ('name', 'European Air Transport Command')]
# [('o', 'http://www.wikidata.org/entity/Q1480793'), ('name', 'Nuclear Suppliers Group')]
# [('o', 'http://www.wikidata.org/entity/Q151991'), ('name', 'European Southern Observatory')]
# [('o', 'http://www.wikidata.org/entity/Q161549'), ('name', 'European Coal and Steel Community')]
# [('o', 'http://www.wikidata.org/entity/Q170424'), ('name', 'World Meteorological Organization')]
# [('o', 'http://www.wikidata.org/entity/Q17495'), ('name', 'Universal Postal Union')]
# [('o', 'http://www.wikidata.org/entity/Q177773'), ('name', 'World Intellectual Property Organization')]
# [('o', 'http://www.wikidata.org/entity/Q188822'), ('name', 'Asian Development Bank')]
# [('o', 'http://www.wikidata.org/entity/Q189946'), ('name', 'Western European Union')]
# [('o', 'http://www.wikidata.org/entity/Q191384'), ('name', 'International Bank for Reconstruction and Development')]
# [('o', 'http://www.wikidata.org/entity/Q192177'), ('name', 'Union for the Mediterranean')]
# [('o', 'http://www.wikidata.org/entity/Q1928989'), ('name', 'Treaty on Open Skies')]
# [('o', 'http://www.wikidata.org/entity/Q1969730'), ('name', 'Schengen Area')]
# [('o', 'http://www.wikidata.org/entity/Q19771'), ('name', 'G20')]
# [('o', 'http://www.wikidata.org/entity/Q201054'), ('name', 'International Maritime Organization')]
# [('o', 'http://www.wikidata.org/entity/Q233611'), ('name', 'International Hydrographic Organization')]
# [('o', 'http://www.wikidata.org/entity/Q340195'), ('name', 'African Development Bank')]
# [('o', 'http://www.wikidata.org/entity/Q37143'), ('name', 'G8')]
# [('o', 'http://www.wikidata.org/entity/Q376150'), ('name', 'International Telecommunication Union')]
# [('o', 'http://www.wikidata.org/entity/Q3772571'), ('name', 'Caribbean Development Bank')]
# [('o', 'http://www.wikidata.org/entity/Q386120'), ('name', 'United Nations Industrial Development Organization')]
# [('o', 'http://www.wikidata.org/entity/Q3866537'), ('name', 'Movement Coordination Centre Europe')]
# [('o', 'http://www.wikidata.org/entity/Q41550'), ('name', 'Organisation for Economic Cooperation and Development')]
# [('o', 'http://www.wikidata.org/entity/Q41984'), ('name', 'International Atomic Energy Agency')]
# [('o', 'http://www.wikidata.org/entity/Q42262'), ('name', 'European Space Agency')]
# [('o', 'http://www.wikidata.org/entity/Q42944'), ('name', 'CERN')]
# [('o', 'http://www.wikidata.org/entity/Q45177'), ('name', 'Visa Waiver Program')]
# [('o', 'http://www.wikidata.org/entity/Q458'), ('name', 'European Union')]
# [('o', 'http://www.wikidata.org/entity/Q47488'), ('name', 'International Criminal Court')]
# [('o', 'http://www.wikidata.org/entity/Q521227'), ('name', 'Organisation for Joint Armament Cooperation')]
# [('o', 'http://www.wikidata.org/entity/Q54129'), ('name', 'International Labour Organization')]
# [('o', 'http://www.wikidata.org/entity/Q5611262'), ('name', 'Group on Earth Observations')]
# [('o', 'http://www.wikidata.org/entity/Q61923'), ('name', 'World Tourism Organization')]
# [('o', 'http://www.wikidata.org/entity/Q656801'), ('name', 'International Finance Corporation')]
# [('o', 'http://www.wikidata.org/entity/Q663492'), ('name', 'Eurocontrol')]
# [('o', 'http://www.wikidata.org/entity/Q689859'), ('name', 'International Fund for Agricultural Development')]
# [('o', 'http://www.wikidata.org/entity/Q7184'), ('name', 'NATO')]
# [('o', 'http://www.wikidata.org/entity/Q7804'), ('name', 'International Monetary Fund')]
# [('o', 'http://www.wikidata.org/entity/Q7809'), ('name', 'UNESCO')]
# [('o', 'http://www.wikidata.org/entity/Q7817'), ('name', 'World Health Organization')]
# [('o', 'http://www.wikidata.org/entity/Q7825'), ('name', 'World Trade Organization')]
# [('o', 'http://www.wikidata.org/entity/Q782942'), ('name', 'Australia Group')]
# [('o', 'http://www.wikidata.org/entity/Q81299'), ('name', 'Organization for Security and Co-operation in Europe')]
# [('o', 'http://www.wikidata.org/entity/Q82151'), ('name', 'Food and Agriculture Organization')]
# [('o', 'http://www.wikidata.org/entity/Q826700'), ('name', 'International Energy Agency')]
# [('o', 'http://www.wikidata.org/entity/Q827525'), ('name', 'International Development Association')]
# [('o', 'http://www.wikidata.org/entity/Q842490'), ('name', 'Organisation for the Prohibition of Chemical Weapons')]
# [('o', 'http://www.wikidata.org/entity/Q8475'), ('name', 'Interpol')]
# [('o', 'http://www.wikidata.org/entity/Q8908'), ('name', 'Council of Europe')]
# [('o', 'http://www.wikidata.org/entity/Q899770'), ('name', 'International Centre for Settlement of Investment Disputes')]
# [('o', 'http://www.wikidata.org/entity/Q132551'), ('name', 'United Nations High Commissioner for Refugees')]
# [('o', 'http://www.wikidata.org/entity/Q699036'), ('name', 'United Nations Truce Supervision Organization')]
# [('o', 'http://www.wikidata.org/entity/Q176815'), ('name', 'Interparliamentary Union')]
# [('o', 'http://www.wikidata.org/entity/Q182000'), ('name', 'United Nations Conference on Trade and Development')]
# [('o', 'http://www.wikidata.org/entity/Q7178'), ('name', 'International Red Cross and Red Crescent Movement')]
# [('o', 'http://www.wikidata.org/entity/Q52847'), ('name', 'European Economic Community')]
# [('o', 'http://www.wikidata.org/entity/Q605326'), ('name', 'World Customs Organization')]
# [('o', 'http://www.wikidata.org/entity/Q472311'), ('name', 'International Organization for Migration')]
# [('o', 'http://www.wikidata.org/entity/Q309195'), ('name', 'Bank for International Settlements')]
# [('o', 'http://www.wikidata.org/entity/Q1045198'), ('name', 'Permanent Court of Arbitration')]
# [('o', 'http://www.wikidata.org/entity/Q1374456'), ('name', 'Euro-Atlantic Partnership Council')]
# [('o', 'http://www.wikidata.org/entity/Q1411881'), ('name', 'Group of Ten')]
# [('o', 'http://www.wikidata.org/entity/Q1666759'), ('name', 'International Mobile Satellite Organization')]
# [('o', 'http://www.wikidata.org/entity/Q18816843'), ('name', 'Procurement G6')]
# 73

# %%
# return all property of European Union (wrong code)
queryString = """
SELECT DISTINCT ?p ?name
WHERE {
   wd:Q468 ?p ?o.
   # get the label
   # ?p sc:name ?name.
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P1080'), ('name', 'from narrative universe')]
# [('p', 'http://www.wikidata.org/prop/direct/P136'), ('name', 'genre')]
# [('p', 'http://www.wikidata.org/prop/direct/P1441'), ('name', 'present in work')]
# [('p', 'http://www.wikidata.org/prop/direct/P170'), ('name', 'creator')]
# [('p', 'http://www.wikidata.org/prop/direct/P1889'), ('name', 'different from')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('name', 'instance of')]
# [('p', 'http://www.wikidata.org/prop/direct/P6262'), ('name', 'Fandom article ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P646'), ('name', 'Freebase ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P973'), ('name', 'described at URL')]
# 9

# %%
# return all property of European Union (correct code)
queryString = """
SELECT DISTINCT ?p ?name
WHERE {
   wd:Q458 ?p ?o.
   # get the label
   # ?p sc:name ?name.
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P1005'), ('name', 'Portuguese National Library ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1051'), ('name', 'PSH ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1081'), ('name', 'Human Development Index')]
# [('p', 'http://www.wikidata.org/prop/direct/P1082'), ('name', 'population')]
# [('p', 'http://www.wikidata.org/prop/direct/P112'), ('name', 'founded by')]
# [('p', 'http://www.wikidata.org/prop/direct/P1125'), ('name', 'Gini coefficient')]
# [('p', 'http://www.wikidata.org/prop/direct/P1151'), ('name', "topic's main Wikimedia portal")]
# [('p', 'http://www.wikidata.org/prop/direct/P1245'), ('name', 'OmegaWiki Defined Meaning')]
# [('p', 'http://www.wikidata.org/prop/direct/P1273'), ('name', 'CANTIC ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1280'), ('name', 'CONOR.SI ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1296'), ('name', 'Gran Enciclopèdia Catalana ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1313'), ('name', 'office held by head of government')]
# [('p', 'http://www.wikidata.org/prop/direct/P1315'), ('name', 'NLA Trove ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1325'), ('name', 'external data available at')]
# [('p', 'http://www.wikidata.org/prop/direct/P1343'), ('name', 'described by source')]
# [('p', 'http://www.wikidata.org/prop/direct/P1344'), ('name', 'participant in')]
# [('p', 'http://www.wikidata.org/prop/direct/P1365'), ('name', 'replaces')]
# [('p', 'http://www.wikidata.org/prop/direct/P1417'), ('name', 'Encyclopædia Britannica Online ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1424'), ('name', "topic's main template")]
# [('p', 'http://www.wikidata.org/prop/direct/P1448'), ('name', 'official name')]
# [('p', 'http://www.wikidata.org/prop/direct/P1451'), ('name', 'motto text')]
# [('p', 'http://www.wikidata.org/prop/direct/P1482'), ('name', 'Stack Exchange tag')]
# [('p', 'http://www.wikidata.org/prop/direct/P150'), ('name', 'contains administrative territorial entity')]
# [('p', 'http://www.wikidata.org/prop/direct/P1546'), ('name', 'motto')]
# [('p', 'http://www.wikidata.org/prop/direct/P1549'), ('name', 'demonym')]
# [('p', 'http://www.wikidata.org/prop/direct/P155'), ('name', 'follows')]
# [('p', 'http://www.wikidata.org/prop/direct/P159'), ('name', 'headquarters location')]
# [('p', 'http://www.wikidata.org/prop/direct/P1617'), ('name', 'BBC Things ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1622'), ('name', 'driving side')]
# [('p', 'http://www.wikidata.org/prop/direct/P163'), ('name', 'flag')]
# [('p', 'http://www.wikidata.org/prop/direct/P166'), ('name', 'award received')]
# [('p', 'http://www.wikidata.org/prop/direct/P1807'), ('name', 'Great Aragonese Encyclopedia ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1813'), ('name', 'short name')]
# [('p', 'http://www.wikidata.org/prop/direct/P1889'), ('name', 'different from')]
# [('p', 'http://www.wikidata.org/prop/direct/P1938'), ('name', 'Project Gutenberg author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P194'), ('name', 'legislative body')]
# [('p', 'http://www.wikidata.org/prop/direct/P2046'), ('name', 'area')]
# [('p', 'http://www.wikidata.org/prop/direct/P208'), ('name', 'executive body')]
# [('p', 'http://www.wikidata.org/prop/direct/P209'), ('name', 'highest judicial authority')]
# [('p', 'http://www.wikidata.org/prop/direct/P213'), ('name', 'ISNI')]
# [('p', 'http://www.wikidata.org/prop/direct/P214'), ('name', 'VIAF ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2184'), ('name', 'history of topic')]
# [('p', 'http://www.wikidata.org/prop/direct/P227'), ('name', 'GND ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P242'), ('name', 'locator map image')]
# [('p', 'http://www.wikidata.org/prop/direct/P2427'), ('name', 'GRID ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P244'), ('name', 'Library of Congress authority ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2581'), ('name', 'BabelNet ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2633'), ('name', 'geography of topic')]
# [('p', 'http://www.wikidata.org/prop/direct/P268'), ('name', 'Bibliothèque nationale de France ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P269'), ('name', 'IdRef ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('name', 'subclass of')]
# [('p', 'http://www.wikidata.org/prop/direct/P2852'), ('name', 'emergency telephone number')]
# [('p', 'http://www.wikidata.org/prop/direct/P2884'), ('name', 'mains voltage')]
# [('p', 'http://www.wikidata.org/prop/direct/P2888'), ('name', 'exact match')]
# [('p', 'http://www.wikidata.org/prop/direct/P2924'), ('name', 'Great Russian Encyclopedia Online ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2959'), ('name', 'permanent duplicated item')]
# [('p', 'http://www.wikidata.org/prop/direct/P30'), ('name', 'continent')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('name', 'instance of')]
# [('p', 'http://www.wikidata.org/prop/direct/P3106'), ('name', 'Guardian topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3153'), ('name', 'Crossref funder ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3188'), ('name', 'Nobel prize ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3221'), ('name', 'New York Times topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3222'), ('name', 'NE.se ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3365'), ('name', 'Treccani ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3417'), ('name', 'Quora topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P349'), ('name', 'National Diet Library ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3509'), ('name', 'Dagens Nyheter topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P355'), ('name', 'subsidiary')]
# [('p', 'http://www.wikidata.org/prop/direct/P3569'), ('name', 'Cultureel Woordenboek ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P36'), ('name', 'capital')]
# [('p', 'http://www.wikidata.org/prop/direct/P3612'), ('name', 'Le Monde diplomatique subject ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P37'), ('name', 'official language')]
# [('p', 'http://www.wikidata.org/prop/direct/P373'), ('name', 'Commons category')]
# [('p', 'http://www.wikidata.org/prop/direct/P3762'), ('name', 'openMLOL author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P38'), ('name', 'currency')]
# [('p', 'http://www.wikidata.org/prop/direct/P3827'), ('name', 'JSTOR topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3847'), ('name', 'Open Library subject ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3916'), ('name', 'UNESCO Thesaurus ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3987'), ('name', 'SHARE Catalogue author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P402'), ('name', 'OpenStreetMap relation ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P409'), ('name', 'Libraries Australia ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P41'), ('name', 'flag image')]
# [('p', 'http://www.wikidata.org/prop/direct/P421'), ('name', 'located in time zone')]
# [('p', 'http://www.wikidata.org/prop/direct/P4223'), ('name', "Treccani's Enciclopedia Italiana ID")]
# [('p', 'http://www.wikidata.org/prop/direct/P4293'), ('name', 'PM20 folder ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P4427'), ('name', 'GACS ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P452'), ('name', 'industry')]
# [('p', 'http://www.wikidata.org/prop/direct/P4527'), ('name', 'UK Parliament thesaurus ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P457'), ('name', 'foundational text')]
# [('p', 'http://www.wikidata.org/prop/direct/P4613'), ('name', 'Encyclopedia of Modern Ukraine ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P463'), ('name', 'member of')]
# [('p', 'http://www.wikidata.org/prop/direct/P47'), ('name', 'shares border with')]
# [('p', 'http://www.wikidata.org/prop/direct/P4725'), ('name', 'C-SPAN organization ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P486'), ('name', 'MeSH descriptor ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P487'), ('name', 'Unicode character')]
# [('p', 'http://www.wikidata.org/prop/direct/P5008'), ('name', 'on focus list of Wikimedia project')]
# [('p', 'http://www.wikidata.org/prop/direct/P5019'), ('name', 'Brockhaus Enzyklopädie online ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5125'), ('name', 'Wikimedia outline')]
# [('p', 'http://www.wikidata.org/prop/direct/P5167'), ('name', 'vehicles per thousand people')]
# [('p', 'http://www.wikidata.org/prop/direct/P5198'), ('name', 'ASC Leiden Thesaurus ID')]
# 100

# %%
# return all property from European Union to Italy
queryString = """
SELECT DISTINCT ?p ?name
WHERE {
   wd:Q458 ?p wd:Q38 .
   # get the label
   # ?p sc:name ?name.
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P112'), ('name', 'founded by')]
# [('p', 'http://www.wikidata.org/prop/direct/P150'), ('name', 'contains administrative territorial entity')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('name', 'has part')]
# 3

# %%
# return all property from Italy to EU
queryString = """
SELECT DISTINCT ?p ?name
WHERE {
   wd:Q38 ?p wd:Q458 .
   # get the label
   # ?p sc:name ?name.
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P463'), ('name', 'member of')]
# 1

# %%
# return all countries belonging to EU
queryString = """
SELECT DISTINCT ?s ?name
WHERE {
   # ?s wdt:P31 wd:Q6256;
      wdt:P463 wd:Q458.

   # ?s sc:name ?name.
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('s', 'http://www.wikidata.org/entity/Q142'), ('name', 'France')]
# [('s', 'http://www.wikidata.org/entity/Q145'), ('name', 'United Kingdom')]
# [('s', 'http://www.wikidata.org/entity/Q211'), ('name', 'Latvia')]
# [('s', 'http://www.wikidata.org/entity/Q213'), ('name', 'Czech Republic')]
# [('s', 'http://www.wikidata.org/entity/Q214'), ('name', 'Slovakia')]
# [('s', 'http://www.wikidata.org/entity/Q218'), ('name', 'Romania')]
# [('s', 'http://www.wikidata.org/entity/Q219'), ('name', 'Bulgaria')]
# [('s', 'http://www.wikidata.org/entity/Q224'), ('name', 'Croatia')]
# [('s', 'http://www.wikidata.org/entity/Q229'), ('name', 'Cyprus')]
# [('s', 'http://www.wikidata.org/entity/Q233'), ('name', 'Malta')]
# [('s', 'http://www.wikidata.org/entity/Q27'), ('name', 'Ireland')]
# [('s', 'http://www.wikidata.org/entity/Q28'), ('name', 'Hungary')]
# [('s', 'http://www.wikidata.org/entity/Q29999'), ('name', 'Kingdom of the Netherlands')]
# [('s', 'http://www.wikidata.org/entity/Q33'), ('name', 'Finland')]
# [('s', 'http://www.wikidata.org/entity/Q34'), ('name', 'Sweden')]
# [('s', 'http://www.wikidata.org/entity/Q35'), ('name', 'Denmark')]
# [('s', 'http://www.wikidata.org/entity/Q36'), ('name', 'Poland')]
# [('s', 'http://www.wikidata.org/entity/Q38'), ('name', 'Italy')]
# [('s', 'http://www.wikidata.org/entity/Q40'), ('name', 'Austria')]
# [('s', 'http://www.wikidata.org/entity/Q41'), ('name', 'Greece')]
# [('s', 'http://www.wikidata.org/entity/Q45'), ('name', 'Portugal')]
# 21

# %%
# return subjects member of EU
queryString = """
SELECT DISTINCT ?s ?name
WHERE {
   # ?s wdt:P463 wd:Q458.

   # ?s sc:name ?name.
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('s', 'http://www.wikidata.org/entity/Q142'), ('name', 'France')]
# [('s', 'http://www.wikidata.org/entity/Q145'), ('name', 'United Kingdom')]
# [('s', 'http://www.wikidata.org/entity/Q183'), ('name', 'Germany')]
# [('s', 'http://www.wikidata.org/entity/Q191'), ('name', 'Estonia')]
# [('s', 'http://www.wikidata.org/entity/Q211'), ('name', 'Latvia')]
# [('s', 'http://www.wikidata.org/entity/Q213'), ('name', 'Czech Republic')]
# [('s', 'http://www.wikidata.org/entity/Q214'), ('name', 'Slovakia')]
# [('s', 'http://www.wikidata.org/entity/Q215'), ('name', 'Slovenia')]
# [('s', 'http://www.wikidata.org/entity/Q218'), ('name', 'Romania')]
# [('s', 'http://www.wikidata.org/entity/Q219'), ('name', 'Bulgaria')]
# [('s', 'http://www.wikidata.org/entity/Q224'), ('name', 'Croatia')]
# [('s', 'http://www.wikidata.org/entity/Q229'), ('name', 'Cyprus')]
# [('s', 'http://www.wikidata.org/entity/Q233'), ('name', 'Malta')]
# [('s', 'http://www.wikidata.org/entity/Q27'), ('name', 'Ireland')]
# [('s', 'http://www.wikidata.org/entity/Q28'), ('name', 'Hungary')]
# [('s', 'http://www.wikidata.org/entity/Q29'), ('name', 'Spain')]
# [('s', 'http://www.wikidata.org/entity/Q29999'), ('name', 'Kingdom of the Netherlands')]
# [('s', 'http://www.wikidata.org/entity/Q31'), ('name', 'Belgium')]
# [('s', 'http://www.wikidata.org/entity/Q32'), ('name', 'Luxembourg')]
# [('s', 'http://www.wikidata.org/entity/Q33'), ('name', 'Finland')]
# [('s', 'http://www.wikidata.org/entity/Q34'), ('name', 'Sweden')]
# [('s', 'http://www.wikidata.org/entity/Q35'), ('name', 'Denmark')]
# [('s', 'http://www.wikidata.org/entity/Q36'), ('name', 'Poland')]
# [('s', 'http://www.wikidata.org/entity/Q37'), ('name', 'Lithuania')]
# [('s', 'http://www.wikidata.org/entity/Q38'), ('name', 'Italy')]
# [('s', 'http://www.wikidata.org/entity/Q40'), ('name', 'Austria')]
# [('s', 'http://www.wikidata.org/entity/Q41'), ('name', 'Greece')]
# [('s', 'http://www.wikidata.org/entity/Q45'), ('name', 'Portugal')]
# 28

# %%
# return all countries member of EU with currency different from Euro
queryString = """
SELECT DISTINCT ?s ?name 
WHERE {
   # ?s wdt:P31 wd:Q6256;
      wdt:P463 wd:Q458;
      wdt:P38 ?currency.
   FILTER(?currency != wd:Q4916)
   
   # ?s sc:name ?name.
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('s', 'http://www.wikidata.org/entity/Q145'), ('name', 'United Kingdom')]
# [('s', 'http://www.wikidata.org/entity/Q213'), ('name', 'Czech Republic')]
# [('s', 'http://www.wikidata.org/entity/Q218'), ('name', 'Romania')]
# [('s', 'http://www.wikidata.org/entity/Q219'), ('name', 'Bulgaria')]
# [('s', 'http://www.wikidata.org/entity/Q224'), ('name', 'Croatia')]
# [('s', 'http://www.wikidata.org/entity/Q28'), ('name', 'Hungary')]
# [('s', 'http://www.wikidata.org/entity/Q34'), ('name', 'Sweden')]
# [('s', 'http://www.wikidata.org/entity/Q35'), ('name', 'Denmark')]
# [('s', 'http://www.wikidata.org/entity/Q36'), ('name', 'Poland')]
# 9

# %%
# return all coutries member of EU with currency different from Euro and their currency
queryString = """ 
SELECT DISTINCT ?s ?name ?currency ?currencyName
WHERE {
   # ?s wdt:P31 wd:Q6256;
      wdt:P463 wd:Q458;
      wdt:P38 ?currency.
   FILTER(?currency != wd:Q4916)
   
   # ?s sc:name ?name.
   # ?currency sc:name ?currencyName.
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('s', 'http://www.wikidata.org/entity/Q36'), ('name', 'Poland'), ('currency', 'http://www.wikidata.org/entity/Q123213'), ('currencyName', 'złoty')]
# [('s', 'http://www.wikidata.org/entity/Q219'), ('name', 'Bulgaria'), ('currency', 'http://www.wikidata.org/entity/Q172540'), ('currencyName', 'Bulgarian lev')]
# [('s', 'http://www.wikidata.org/entity/Q28'), ('name', 'Hungary'), ('currency', 'http://www.wikidata.org/entity/Q47190'), ('currencyName', 'forint')]
# [('s', 'http://www.wikidata.org/entity/Q218'), ('name', 'Romania'), ('currency', 'http://www.wikidata.org/entity/Q131645'), ('currencyName', 'Romanian leu')]
# [('s', 'http://www.wikidata.org/entity/Q145'), ('name', 'United Kingdom'), ('currency', 'http://www.wikidata.org/entity/Q25224'), ('currencyName', 'pound sterling')]
# [('s', 'http://www.wikidata.org/entity/Q224'), ('name', 'Croatia'), ('currency', 'http://www.wikidata.org/entity/Q26360'), ('currencyName', 'Croatian kuna')]
# [('s', 'http://www.wikidata.org/entity/Q213'), ('name', 'Czech Republic'), ('currency', 'http://www.wikidata.org/entity/Q131016'), ('currencyName', 'Czech koruna')]
# [('s', 'http://www.wikidata.org/entity/Q35'), ('name', 'Denmark'), ('currency', 'http://www.wikidata.org/entity/Q25417'), ('currencyName', 'Danish krone')]
# [('s', 'http://www.wikidata.org/entity/Q34'), ('name', 'Sweden'), ('currency', 'http://www.wikidata.org/entity/Q122922'), ('currencyName', 'Swedish krona')]
# 9

# %%
#Return the countries member of the European Union, with a currency different from the Euro (return also their currency).
#using * operator
queryString = """ 
SELECT DISTINCT ?s ?name ?currency ?currencyName
WHERE {
   # ?s wdt:P31 ?class;
      wdt:P463 wd:Q458;
      wdt:P38 ?currency.
   # ?class wdt:P279* wd:Q6256
   FILTER(?currency != wd:Q4916)
   
   # ?s sc:name ?name.
   # ?currency sc:name ?currencyName.
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('s', 'http://www.wikidata.org/entity/Q145'), ('name', 'United Kingdom'), ('currency', 'http://www.wikidata.org/entity/Q25224'), ('currencyName', 'pound sterling')]
# [('s', 'http://www.wikidata.org/entity/Q213'), ('name', 'Czech Republic'), ('currency', 'http://www.wikidata.org/entity/Q131016'), ('currencyName', 'Czech koruna')]
# [('s', 'http://www.wikidata.org/entity/Q218'), ('name', 'Romania'), ('currency', 'http://www.wikidata.org/entity/Q131645'), ('currencyName', 'Romanian leu')]
# [('s', 'http://www.wikidata.org/entity/Q219'), ('name', 'Bulgaria'), ('currency', 'http://www.wikidata.org/entity/Q172540'), ('currencyName', 'Bulgarian lev')]
# [('s', 'http://www.wikidata.org/entity/Q224'), ('name', 'Croatia'), ('currency', 'http://www.wikidata.org/entity/Q26360'), ('currencyName', 'Croatian kuna')]
# [('s', 'http://www.wikidata.org/entity/Q28'), ('name', 'Hungary'), ('currency', 'http://www.wikidata.org/entity/Q47190'), ('currencyName', 'forint')]
# [('s', 'http://www.wikidata.org/entity/Q34'), ('name', 'Sweden'), ('currency', 'http://www.wikidata.org/entity/Q122922'), ('currencyName', 'Swedish krona')]
# [('s', 'http://www.wikidata.org/entity/Q35'), ('name', 'Denmark'), ('currency', 'http://www.wikidata.org/entity/Q25417'), ('currencyName', 'Danish krone')]
# [('s', 'http://www.wikidata.org/entity/Q36'), ('name', 'Poland'), ('currency', 'http://www.wikidata.org/entity/Q123213'), ('currencyName', 'złoty')]
# 9

# %%
# return all countries member of EU with currency different from Euro and their currency 
#(instance of country with * operator on instance of)
queryString = """ 
SELECT DISTINCT ?s ?name ?currency ?currencyName
WHERE {
   # ?s wdt:P31* wd:Q6256;
      wdt:P463 wd:Q458;
      wdt:P38 ?currency.
   FILTER(?currency != wd:Q4916)
   
   # ?s sc:name ?name.
   # ?currency sc:name ?currencyName.
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('s', 'http://www.wikidata.org/entity/Q145'), ('name', 'United Kingdom'), ('currency', 'http://www.wikidata.org/entity/Q25224'), ('currencyName', 'pound sterling')]
# [('s', 'http://www.wikidata.org/entity/Q213'), ('name', 'Czech Republic'), ('currency', 'http://www.wikidata.org/entity/Q131016'), ('currencyName', 'Czech koruna')]
# [('s', 'http://www.wikidata.org/entity/Q218'), ('name', 'Romania'), ('currency', 'http://www.wikidata.org/entity/Q131645'), ('currencyName', 'Romanian leu')]
# [('s', 'http://www.wikidata.org/entity/Q219'), ('name', 'Bulgaria'), ('currency', 'http://www.wikidata.org/entity/Q172540'), ('currencyName', 'Bulgarian lev')]
# [('s', 'http://www.wikidata.org/entity/Q224'), ('name', 'Croatia'), ('currency', 'http://www.wikidata.org/entity/Q26360'), ('currencyName', 'Croatian kuna')]
# [('s', 'http://www.wikidata.org/entity/Q28'), ('name', 'Hungary'), ('currency', 'http://www.wikidata.org/entity/Q47190'), ('currencyName', 'forint')]
# [('s', 'http://www.wikidata.org/entity/Q34'), ('name', 'Sweden'), ('currency', 'http://www.wikidata.org/entity/Q122922'), ('currencyName', 'Swedish krona')]
# [('s', 'http://www.wikidata.org/entity/Q35'), ('name', 'Denmark'), ('currency', 'http://www.wikidata.org/entity/Q25417'), ('currencyName', 'Danish krone')]
# [('s', 'http://www.wikidata.org/entity/Q36'), ('name', 'Poland'), ('currency', 'http://www.wikidata.org/entity/Q123213'), ('currencyName', 'złoty')]
# 9

# %%
#Return the countries (instance of country or a subclass of it) belonging to the European Union, with a currency different from the Euro 
queryString = """ 
SELECT DISTINCT ?s ?name ?currency ?currencyName
WHERE {
   # ?s wdt:P31/wdt:P279* wd:Q6256;
      wdt:P463 wd:Q458;
      wdt:P38 ?currency.
   FILTER(?currency != wd:Q4916)
   
   # ?s sc:name ?name.
   # ?currency sc:name ?currencyName.
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('s', 'http://www.wikidata.org/entity/Q145'), ('name', 'United Kingdom'), ('currency', 'http://www.wikidata.org/entity/Q25224'), ('currencyName', 'pound sterling')]
# [('s', 'http://www.wikidata.org/entity/Q213'), ('name', 'Czech Republic'), ('currency', 'http://www.wikidata.org/entity/Q131016'), ('currencyName', 'Czech koruna')]
# [('s', 'http://www.wikidata.org/entity/Q218'), ('name', 'Romania'), ('currency', 'http://www.wikidata.org/entity/Q131645'), ('currencyName', 'Romanian leu')]
# [('s', 'http://www.wikidata.org/entity/Q219'), ('name', 'Bulgaria'), ('currency', 'http://www.wikidata.org/entity/Q172540'), ('currencyName', 'Bulgarian lev')]
# [('s', 'http://www.wikidata.org/entity/Q224'), ('name', 'Croatia'), ('currency', 'http://www.wikidata.org/entity/Q26360'), ('currencyName', 'Croatian kuna')]
# [('s', 'http://www.wikidata.org/entity/Q28'), ('name', 'Hungary'), ('currency', 'http://www.wikidata.org/entity/Q47190'), ('currencyName', 'forint')]
# [('s', 'http://www.wikidata.org/entity/Q34'), ('name', 'Sweden'), ('currency', 'http://www.wikidata.org/entity/Q122922'), ('currencyName', 'Swedish krona')]
# [('s', 'http://www.wikidata.org/entity/Q35'), ('name', 'Denmark'), ('currency', 'http://www.wikidata.org/entity/Q25417'), ('currencyName', 'Danish krone')]
# [('s', 'http://www.wikidata.org/entity/Q36'), ('name', 'Poland'), ('currency', 'http://www.wikidata.org/entity/Q123213'), ('currencyName', 'złoty')]
# 9

# %% [markdown]
# Final query for this task

# %%
# write your final query
queryString = """ 
SELECT DISTINCT ?s ?name ?currency ?currencyName
WHERE {
   # ?s wdt:P31/wdt:P279* wd:Q6256;
      wdt:P463 wd:Q458;
      wdt:P38 ?currency.
   FILTER(?currency != wd:Q4916)
   
   # ?s sc:name ?name.
   # ?currency sc:name ?currencyName.
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('s', 'http://www.wikidata.org/entity/Q145'), ('name', 'United Kingdom'), ('currency', 'http://www.wikidata.org/entity/Q25224'), ('currencyName', 'pound sterling')]
# [('s', 'http://www.wikidata.org/entity/Q213'), ('name', 'Czech Republic'), ('currency', 'http://www.wikidata.org/entity/Q131016'), ('currencyName', 'Czech koruna')]
# [('s', 'http://www.wikidata.org/entity/Q218'), ('name', 'Romania'), ('currency', 'http://www.wikidata.org/entity/Q131645'), ('currencyName', 'Romanian leu')]
# [('s', 'http://www.wikidata.org/entity/Q219'), ('name', 'Bulgaria'), ('currency', 'http://www.wikidata.org/entity/Q172540'), ('currencyName', 'Bulgarian lev')]
# [('s', 'http://www.wikidata.org/entity/Q224'), ('name', 'Croatia'), ('currency', 'http://www.wikidata.org/entity/Q26360'), ('currencyName', 'Croatian kuna')]
# [('s', 'http://www.wikidata.org/entity/Q28'), ('name', 'Hungary'), ('currency', 'http://www.wikidata.org/entity/Q47190'), ('currencyName', 'forint')]
# [('s', 'http://www.wikidata.org/entity/Q34'), ('name', 'Sweden'), ('currency', 'http://www.wikidata.org/entity/Q122922'), ('currencyName', 'Swedish krona')]
# [('s', 'http://www.wikidata.org/entity/Q35'), ('name', 'Denmark'), ('currency', 'http://www.wikidata.org/entity/Q25417'), ('currencyName', 'Danish krone')]
# [('s', 'http://www.wikidata.org/entity/Q36'), ('name', 'Poland'), ('currency', 'http://www.wikidata.org/entity/Q123213'), ('currencyName', 'złoty')]
# 9

# %% [markdown]
# ## Task 4
# For each country that now uses Euro return which was the currencies used before

# %%
#return all properties for currency
queryString = """
SELECT DISTINCT ?p ?name
WHERE {
   # bind something
   wd:Q8142 ?p ?obj .
   # get the label
   # ?p sc:name ?name.
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P1051'), ('name', 'PSH ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1245'), ('name', 'OmegaWiki Defined Meaning')]
# [('p', 'http://www.wikidata.org/prop/direct/P1282'), ('name', 'OpenStreetMap tag or key')]
# [('p', 'http://www.wikidata.org/prop/direct/P1343'), ('name', 'described by source')]
# [('p', 'http://www.wikidata.org/prop/direct/P1417'), ('name', 'Encyclopædia Britannica Online ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1424'), ('name', "topic's main template")]
# [('p', 'http://www.wikidata.org/prop/direct/P1482'), ('name', 'Stack Exchange tag')]
# [('p', 'http://www.wikidata.org/prop/direct/P1687'), ('name', 'Wikidata property')]
# [('p', 'http://www.wikidata.org/prop/direct/P18'), ('name', 'image')]
# [('p', 'http://www.wikidata.org/prop/direct/P1889'), ('name', 'different from')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('name', 'properties for this type')]
# [('p', 'http://www.wikidata.org/prop/direct/P2184'), ('name', 'history of topic')]
# [('p', 'http://www.wikidata.org/prop/direct/P227'), ('name', 'GND ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2347'), ('name', 'YSO ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2354'), ('name', 'has list')]
# [('p', 'http://www.wikidata.org/prop/direct/P244'), ('name', 'Library of Congress authority ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2581'), ('name', 'BabelNet ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('name', 'subclass of')]
# [('p', 'http://www.wikidata.org/prop/direct/P3106'), ('name', 'Guardian topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3417'), ('name', 'Quora topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3479'), ('name', 'Omni topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3612'), ('name', 'Le Monde diplomatique subject ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P373'), ('name', 'Commons category')]
# [('p', 'http://www.wikidata.org/prop/direct/P3827'), ('name', 'JSTOR topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3916'), ('name', 'UNESCO Thesaurus ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P4254'), ('name', 'Bengali Banglapedia ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P4342'), ('name', 'Store norske leksikon ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P4527'), ('name', 'UK Parliament thesaurus ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P4613'), ('name', 'Encyclopedia of Modern Ukraine ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5008'), ('name', 'on focus list of Wikimedia project')]
# [('p', 'http://www.wikidata.org/prop/direct/P508'), ('name', 'BNCF Thesaurus ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5198'), ('name', 'ASC Leiden Thesaurus ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5247'), ('name', 'Giant Bomb ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5250'), ('name', 'IAB code')]
# [('p', 'http://www.wikidata.org/prop/direct/P5357'), ('name', 'The Encyclopedia of Science Fiction ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5748'), ('name', 'Basisklassifikation')]
# [('p', 'http://www.wikidata.org/prop/direct/P5869'), ('name', 'model item')]
# [('p', 'http://www.wikidata.org/prop/direct/P6366'), ('name', 'Microsoft Academic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P646'), ('name', 'Freebase ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6573'), ('name', 'Klexikon article ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7844'), ('name', 'Joconde object type ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8248'), ('name', 'Colon Classification')]
# [('p', 'http://www.wikidata.org/prop/direct/P8408'), ('name', 'KBpedia ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P910'), ('name', "topic's main category")]
# [('p', 'http://www.wikidata.org/prop/direct/P973'), ('name', 'described at URL')]
# [('p', 'http://www.wikidata.org/prop/direct/P9475'), ('name', 'Encyclopedia of Korean Culture ID')]
# 46

# %%
#return superclasses for currency
queryString = """
SELECT DISTINCT ?obj ?name
WHERE {
   wd:Q8142 wdt:P279 ?obj .
   # ?obj sc:name ?name.
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('obj', 'http://www.wikidata.org/entity/Q11105360'), ('name', 'medium of exchange')]
# [('obj', 'http://www.wikidata.org/entity/Q47574'), ('name', 'unit of measurement')]
# [('obj', 'http://www.wikidata.org/entity/Q831772'), ('name', 'foreign currencies')]
# [('obj', 'http://www.wikidata.org/entity/Q1368'), ('name', 'money')]
# 4

# %%
## return all properties for Greece
queryString = """
SELECT DISTINCT ?p ?name
WHERE {
   wd:Q41 ?p ?o.
   # get the label
   # ?p sc:name ?name.
}
LIMIT 300
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P1036'), ('name', 'Dewey Decimal Classification')]
# [('p', 'http://www.wikidata.org/prop/direct/P1081'), ('name', 'Human Development Index')]
# [('p', 'http://www.wikidata.org/prop/direct/P1082'), ('name', 'population')]
# [('p', 'http://www.wikidata.org/prop/direct/P1151'), ('name', "topic's main Wikimedia portal")]
# [('p', 'http://www.wikidata.org/prop/direct/P1198'), ('name', 'unemployment rate')]
# [('p', 'http://www.wikidata.org/prop/direct/P1225'), ('name', 'U.S. National Archives Identifier')]
# [('p', 'http://www.wikidata.org/prop/direct/P1245'), ('name', 'OmegaWiki Defined Meaning')]
# [('p', 'http://www.wikidata.org/prop/direct/P1296'), ('name', 'Gran Enciclopèdia Catalana ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1304'), ('name', 'central bank')]
# [('p', 'http://www.wikidata.org/prop/direct/P1313'), ('name', 'office held by head of government')]
# [('p', 'http://www.wikidata.org/prop/direct/P1343'), ('name', 'described by source')]
# [('p', 'http://www.wikidata.org/prop/direct/P1344'), ('name', 'participant in')]
# [('p', 'http://www.wikidata.org/prop/direct/P1365'), ('name', 'replaces')]
# [('p', 'http://www.wikidata.org/prop/direct/P138'), ('name', 'named after')]
# [('p', 'http://www.wikidata.org/prop/direct/P1417'), ('name', 'Encyclopædia Britannica Online ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1438'), ('name', 'Jewish Encyclopedia ID (Russian)')]
# [('p', 'http://www.wikidata.org/prop/direct/P1451'), ('name', 'motto text')]
# [('p', 'http://www.wikidata.org/prop/direct/P1464'), ('name', 'category for people born here')]
# [('p', 'http://www.wikidata.org/prop/direct/P1465'), ('name', 'category for people who died here')]
# [('p', 'http://www.wikidata.org/prop/direct/P150'), ('name', 'contains administrative territorial entity')]
# [('p', 'http://www.wikidata.org/prop/direct/P1546'), ('name', 'motto')]
# [('p', 'http://www.wikidata.org/prop/direct/P1549'), ('name', 'demonym')]
# [('p', 'http://www.wikidata.org/prop/direct/P1552'), ('name', 'has quality')]
# [('p', 'http://www.wikidata.org/prop/direct/P1566'), ('name', 'GeoNames ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1584'), ('name', 'Pleiades ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1589'), ('name', 'lowest point')]
# [('p', 'http://www.wikidata.org/prop/direct/P1622'), ('name', 'driving side')]
# [('p', 'http://www.wikidata.org/prop/direct/P163'), ('name', 'flag')]
# [('p', 'http://www.wikidata.org/prop/direct/P1667'), ('name', 'Getty Thesaurus of Geographic Names ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P17'), ('name', 'country')]
# [('p', 'http://www.wikidata.org/prop/direct/P172'), ('name', 'ethnic group')]
# [('p', 'http://www.wikidata.org/prop/direct/P1740'), ('name', 'category for films shot at this location')]
# [('p', 'http://www.wikidata.org/prop/direct/P1791'), ('name', 'category of people buried here')]
# [('p', 'http://www.wikidata.org/prop/direct/P1792'), ('name', 'category of associated people')]
# [('p', 'http://www.wikidata.org/prop/direct/P18'), ('name', 'image')]
# [('p', 'http://www.wikidata.org/prop/direct/P1906'), ('name', 'office held by head of state')]
# [('p', 'http://www.wikidata.org/prop/direct/P194'), ('name', 'legislative body')]
# [('p', 'http://www.wikidata.org/prop/direct/P2004'), ('name', 'NALT ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2046'), ('name', 'area')]
# [('p', 'http://www.wikidata.org/prop/direct/P206'), ('name', 'located in or next to body of water')]
# [('p', 'http://www.wikidata.org/prop/direct/P208'), ('name', 'executive body')]
# [('p', 'http://www.wikidata.org/prop/direct/P213'), ('name', 'ISNI')]
# [('p', 'http://www.wikidata.org/prop/direct/P214'), ('name', 'VIAF ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2163'), ('name', 'FAST ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2184'), ('name', 'history of topic')]
# [('p', 'http://www.wikidata.org/prop/direct/P2250'), ('name', 'life expectancy')]
# [('p', 'http://www.wikidata.org/prop/direct/P2258'), ('name', 'mobile country code')]
# [('p', 'http://www.wikidata.org/prop/direct/P227'), ('name', 'GND ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2347'), ('name', 'YSO ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P237'), ('name', 'coat of arms')]
# [('p', 'http://www.wikidata.org/prop/direct/P242'), ('name', 'locator map image')]
# [('p', 'http://www.wikidata.org/prop/direct/P244'), ('name', 'Library of Congress authority ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2572'), ('name', 'hashtag')]
# [('p', 'http://www.wikidata.org/prop/direct/P2573'), ('name', 'number of out-of-school children')]
# [('p', 'http://www.wikidata.org/prop/direct/P2579'), ('name', 'studied by')]
# [('p', 'http://www.wikidata.org/prop/direct/P2581'), ('name', 'BabelNet ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2596'), ('name', 'culture')]
# [('p', 'http://www.wikidata.org/prop/direct/P2633'), ('name', 'geography of topic')]
# [('p', 'http://www.wikidata.org/prop/direct/P268'), ('name', 'Bibliothèque nationale de France ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P269'), ('name', 'IdRef ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2852'), ('name', 'emergency telephone number')]
# [('p', 'http://www.wikidata.org/prop/direct/P2853'), ('name', 'electrical plug type')]
# [('p', 'http://www.wikidata.org/prop/direct/P2855'), ('name', 'VAT-rate')]
# [('p', 'http://www.wikidata.org/prop/direct/P2884'), ('name', 'mains voltage')]
# [('p', 'http://www.wikidata.org/prop/direct/P2924'), ('name', 'Great Russian Encyclopedia Online ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2936'), ('name', 'language used')]
# [('p', 'http://www.wikidata.org/prop/direct/P2959'), ('name', 'permanent duplicated item')]
# [('p', 'http://www.wikidata.org/prop/direct/P297'), ('name', 'ISO 3166-1 alpha-2 code')]
# [('p', 'http://www.wikidata.org/prop/direct/P2979'), ('name', 'maritime identification digits')]
# [('p', 'http://www.wikidata.org/prop/direct/P298'), ('name', 'ISO 3166-1 alpha-3 code')]
# [('p', 'http://www.wikidata.org/prop/direct/P2981'), ('name', 'UIC alphabetical country code')]
# [('p', 'http://www.wikidata.org/prop/direct/P2982'), ('name', 'UIC numerical country code')]
# [('p', 'http://www.wikidata.org/prop/direct/P299'), ('name', 'ISO 3166-1 numeric code')]
# [('p', 'http://www.wikidata.org/prop/direct/P2997'), ('name', 'age of majority')]
# [('p', 'http://www.wikidata.org/prop/direct/P30'), ('name', 'continent')]
# [('p', 'http://www.wikidata.org/prop/direct/P3000'), ('name', 'marriageable age')]
# [('p', 'http://www.wikidata.org/prop/direct/P3001'), ('name', 'retirement age')]
# [('p', 'http://www.wikidata.org/prop/direct/P3021'), ('name', 'Iranica ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3024'), ('name', 'ITU letter code')]
# [('p', 'http://www.wikidata.org/prop/direct/P3067'), ('name', 'GS1 country code')]
# [('p', 'http://www.wikidata.org/prop/direct/P3068'), ('name', 'WIPO ST.3')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('name', 'instance of')]
# [('p', 'http://www.wikidata.org/prop/direct/P3106'), ('name', 'Guardian topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3175'), ('name', 'Statoids ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3219'), ('name', 'Encyclopædia Universalis ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3221'), ('name', 'New York Times topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3222'), ('name', 'NE.se ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3241'), ('name', 'Catholic Encyclopedia ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3270'), ('name', 'compulsory education (minimum age)')]
# [('p', 'http://www.wikidata.org/prop/direct/P3271'), ('name', 'compulsory education (maximum age)')]
# [('p', 'http://www.wikidata.org/prop/direct/P3348'), ('name', 'National Library of Greece ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3365'), ('name', 'Treccani ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3417'), ('name', 'Quora topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3422'), ('name', 'INSEE countries and foreign territories code')]
# [('p', 'http://www.wikidata.org/prop/direct/P349'), ('name', 'National Diet Library ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P35'), ('name', 'head of state')]
# [('p', 'http://www.wikidata.org/prop/direct/P3500'), ('name', 'Ringgold ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3509'), ('name', 'Dagens Nyheter topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3553'), ('name', 'Zhihu topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P36'), ('name', 'capital')]
# [('p', 'http://www.wikidata.org/prop/direct/P361'), ('name', 'part of')]
# [('p', 'http://www.wikidata.org/prop/direct/P3612'), ('name', 'Le Monde diplomatique subject ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P37'), ('name', 'official language')]
# [('p', 'http://www.wikidata.org/prop/direct/P373'), ('name', 'Commons category')]
# [('p', 'http://www.wikidata.org/prop/direct/P3743'), ('name', 'ITU/ISO/IEC object identifier')]
# [('p', 'http://www.wikidata.org/prop/direct/P38'), ('name', 'currency')]
# [('p', 'http://www.wikidata.org/prop/direct/P3896'), ('name', 'geoshape')]
# [('p', 'http://www.wikidata.org/prop/direct/P3911'), ('name', 'STW Thesaurus for Economics ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3916'), ('name', 'UNESCO Thesaurus ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P395'), ('name', 'licence plate code')]
# [('p', 'http://www.wikidata.org/prop/direct/P3984'), ('name', 'subreddit')]
# [('p', 'http://www.wikidata.org/prop/direct/P402'), ('name', 'OpenStreetMap relation ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P41'), ('name', 'flag image')]
# [('p', 'http://www.wikidata.org/prop/direct/P421'), ('name', 'located in time zone')]
# [('p', 'http://www.wikidata.org/prop/direct/P4212'), ('name', 'PACTOLS thesaurus ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P4427'), ('name', 'GACS ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P443'), ('name', 'pronunciation audio')]
# [('p', 'http://www.wikidata.org/prop/direct/P4527'), ('name', 'UK Parliament thesaurus ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P4613'), ('name', 'Encyclopedia of Modern Ukraine ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P463'), ('name', 'member of')]
# [('p', 'http://www.wikidata.org/prop/direct/P4672'), ('name', 'EMLO location ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P47'), ('name', 'shares border with')]
# [('p', 'http://www.wikidata.org/prop/direct/P474'), ('name', 'country calling code')]
# [('p', 'http://www.wikidata.org/prop/direct/P4801'), ('name', 'LoC and MARC vocabularies ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P4841'), ('name', 'total fertility rate')]
# [('p', 'http://www.wikidata.org/prop/direct/P486'), ('name', 'MeSH descriptor ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P487'), ('name', 'Unicode character')]
# [('p', 'http://www.wikidata.org/prop/direct/P5002'), ('name', 'Orthodox Encyclopedia ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5008'), ('name', 'on focus list of Wikimedia project')]
# [('p', 'http://www.wikidata.org/prop/direct/P5019'), ('name', 'Brockhaus Enzyklopädie online ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5063'), ('name', 'Interlingual Index ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P51'), ('name', 'audio')]
# [('p', 'http://www.wikidata.org/prop/direct/P5125'), ('name', 'Wikimedia outline')]
# [('p', 'http://www.wikidata.org/prop/direct/P5180'), ('name', 'CIVICUS Monitor country entry')]
# [('p', 'http://www.wikidata.org/prop/direct/P5198'), ('name', 'ASC Leiden Thesaurus ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5247'), ('name', 'Giant Bomb ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5250'), ('name', 'IAB code')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('name', 'has part')]
# [('p', 'http://www.wikidata.org/prop/direct/P530'), ('name', 'diplomatic relation')]
# [('p', 'http://www.wikidata.org/prop/direct/P5400'), ('name', 'GeoNLP ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5437'), ('name', 'EuroVoc ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5456'), ('name', 'TasteAtlas ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5573'), ('name', 'archINFORM location ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5587'), ('name', 'Libris-URI')]
# [('p', 'http://www.wikidata.org/prop/direct/P5658'), ('name', 'railway traffic side')]
# [('p', 'http://www.wikidata.org/prop/direct/P5698'), ('name', 'Invasive Species Compendium Datasheet ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P571'), ('name', 'inception')]
# [('p', 'http://www.wikidata.org/prop/direct/P5748'), ('name', 'Basisklassifikation')]
# [('p', 'http://www.wikidata.org/prop/direct/P5843'), ('name', 'Gynopedia ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5905'), ('name', 'Comic Vine ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6'), ('name', 'head of government')]
# [('p', 'http://www.wikidata.org/prop/direct/P605'), ('name', 'NUTS code')]
# [('p', 'http://www.wikidata.org/prop/direct/P610'), ('name', 'highest point')]
# [('p', 'http://www.wikidata.org/prop/direct/P6104'), ('name', 'maintained by WikiProject')]
# [('p', 'http://www.wikidata.org/prop/direct/P6200'), ('name', 'BBC News topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6293'), ('name', 'YSA ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6385'), ('name', 'Krugosvet article')]
# [('p', 'http://www.wikidata.org/prop/direct/P6404'), ('name', "Treccani's Dizionario di Storia ID")]
# [('p', 'http://www.wikidata.org/prop/direct/P646'), ('name', 'Freebase ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6573'), ('name', 'Klexikon article ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6706'), ('name', 'De Agostini ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6766'), ('name', "Who's on First ID")]
# [('p', 'http://www.wikidata.org/prop/direct/P6839'), ('name', 'TV Tropes identifier')]
# [('p', 'http://www.wikidata.org/prop/direct/P6849'), ('name', 'DR topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P691'), ('name', 'NKCR AUT ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7012'), ('name', 'World Encyclopedia of Puppetry Arts ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P706'), ('name', 'located in/on physical feature')]
# [('p', 'http://www.wikidata.org/prop/direct/P7157'), ('name', 'The Top Tens ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7295'), ('name', 'Gregorian calendar start date')]
# [('p', 'http://www.wikidata.org/prop/direct/P7322'), ('name', 'Marine Regions Geographic IDentifier (MRGID)')]
# [('p', 'http://www.wikidata.org/prop/direct/P7471'), ('name', 'iNaturalist place ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P78'), ('name', 'top-level Internet domain')]
# [('p', 'http://www.wikidata.org/prop/direct/P7818'), ('name', 'French Vikidia ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7822'), ('name', 'Italian Vikidia ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7827'), ('name', 'Spanish Vikidia ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7829'), ('name', 'English Vikidia ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7832'), ('name', 'Basque Vikidia ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7850'), ('name', 'Joconde location ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7859'), ('name', 'WorldCat Identities ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7867'), ('name', 'category for maps')]
# [('p', 'http://www.wikidata.org/prop/direct/P7870'), ('name', 'Analysis & Policy Observatory term ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7960'), ('name', 'Joconde discovery ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8061'), ('name', 'AGROVOC ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8217'), ('name', 'iDAI.gazetteer ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8309'), ('name', 'Yle topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P832'), ('name', 'public holiday')]
# [('p', 'http://www.wikidata.org/prop/direct/P8402'), ('name', 'open data portal')]
# [('p', 'http://www.wikidata.org/prop/direct/P8406'), ('name', 'Grove Art Online ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8408'), ('name', 'KBpedia ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8432'), ('name', 'Österreichisches Musiklexikon Online ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P85'), ('name', 'anthem')]
# [('p', 'http://www.wikidata.org/prop/direct/P8519'), ('name', 'RKD thesaurus ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P856'), ('name', 'official website')]
# [('p', 'http://www.wikidata.org/prop/direct/P8625'), ('name', 'bibliography')]
# [('p', 'http://www.wikidata.org/prop/direct/P8744'), ('name', 'economy of topic')]
# [('p', 'http://www.wikidata.org/prop/direct/P8814'), ('name', 'WordNet 3.1 Synset ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8826'), ('name', 'edition humboldt digital ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8935'), ('name', 'Encyclopedia of the History of Ukraine ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8974'), ('name', 'SAPA ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P898'), ('name', 'IPA transcription')]
# [('p', 'http://www.wikidata.org/prop/direct/P901'), ('name', 'FIPS 10-4 (countries and regions)')]
# [('p', 'http://www.wikidata.org/prop/direct/P9037'), ('name', 'BHCL UUID')]
# [('p', 'http://www.wikidata.org/prop/direct/P910'), ('name', "topic's main category")]
# [('p', 'http://www.wikidata.org/prop/direct/P9100'), ('name', 'GitHub topic')]
# [('p', 'http://www.wikidata.org/prop/direct/P9241'), ('name', 'demographics of topic')]
# [('p', 'http://www.wikidata.org/prop/direct/P9293'), ('name', 'AIATSIS Place Thesaurus ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P9318'), ('name', 'Ávvir topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P935'), ('name', 'Commons gallery')]
# [('p', 'http://www.wikidata.org/prop/direct/P9368'), ('name', 'CNA topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P94'), ('name', 'coat of arms image')]
# [('p', 'http://www.wikidata.org/prop/direct/P948'), ('name', 'page banner')]
# [('p', 'http://www.wikidata.org/prop/direct/P949'), ('name', 'National Library of Israel ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P9498'), ('name', 'Enzyklopädie des europäischen Ostens ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P9629'), ('name', 'Armeniapedia ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P9757'), ('name', 'Schoenberg Database of Manuscripts place ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P982'), ('name', 'MusicBrainz area ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P984'), ('name', 'IOC country code')]
# [('p', 'http://www.wikidata.org/prop/direct/P9886'), ('name', 'TermCymru ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P998'), ('name', 'Curlie ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2964'), ('name', 'right to vote')]
# 220

# %%
## return currency for Greece
queryString = """
SELECT DISTINCT ?o ?name
WHERE {
   wd:Q41 wdt:P38 ?o.
   # get the label
   # ?o sc:name ?name.
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('o', 'http://www.wikidata.org/entity/Q4916'), ('name', 'euro')]
# 1

# %%
# return currency for Slovakia
queryString = """
SELECT DISTINCT ?o ?name
WHERE {
   wd:Q214 wdt:P38 ?o.
   # get the label
   # ?o sc:name ?name.
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('o', 'http://www.wikidata.org/entity/Q4916'), ('name', 'euro')]
# 1

# %%
## return properties for Euro
queryString = """
SELECT ?p ?name
WHERE {
   wd:Q4916 ?p ?o.
   # get the label
   # ?p sc:name ?name.
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P1001'), ('name', 'applies to jurisdiction')]
# [('p', 'http://www.wikidata.org/prop/direct/P1245'), ('name', 'OmegaWiki Defined Meaning')]
# [('p', 'http://www.wikidata.org/prop/direct/P1282'), ('name', 'OpenStreetMap tag or key')]
# [('p', 'http://www.wikidata.org/prop/direct/P1365'), ('name', 'replaces')]
# [('p', 'http://www.wikidata.org/prop/direct/P1365'), ('name', 'replaces')]
# [('p', 'http://www.wikidata.org/prop/direct/P1365'), ('name', 'replaces')]
# [('p', 'http://www.wikidata.org/prop/direct/P1365'), ('name', 'replaces')]
# [('p', 'http://www.wikidata.org/prop/direct/P1365'), ('name', 'replaces')]
# [('p', 'http://www.wikidata.org/prop/direct/P1365'), ('name', 'replaces')]
# [('p', 'http://www.wikidata.org/prop/direct/P1365'), ('name', 'replaces')]
# [('p', 'http://www.wikidata.org/prop/direct/P1365'), ('name', 'replaces')]
# [('p', 'http://www.wikidata.org/prop/direct/P1365'), ('name', 'replaces')]
# [('p', 'http://www.wikidata.org/prop/direct/P1365'), ('name', 'replaces')]
# [('p', 'http://www.wikidata.org/prop/direct/P1365'), ('name', 'replaces')]
# [('p', 'http://www.wikidata.org/prop/direct/P1365'), ('name', 'replaces')]
# [('p', 'http://www.wikidata.org/prop/direct/P1365'), ('name', 'replaces')]
# [('p', 'http://www.wikidata.org/prop/direct/P1365'), ('name', 'replaces')]
# [('p', 'http://www.wikidata.org/prop/direct/P1365'), ('name', 'replaces')]
# [('p', 'http://www.wikidata.org/prop/direct/P1365'), ('name', 'replaces')]
# [('p', 'http://www.wikidata.org/prop/direct/P1365'), ('name', 'replaces')]
# [('p', 'http://www.wikidata.org/prop/direct/P1365'), ('name', 'replaces')]
# [('p', 'http://www.wikidata.org/prop/direct/P1365'), ('name', 'replaces')]
# [('p', 'http://www.wikidata.org/prop/direct/P1365'), ('name', 'replaces')]
# [('p', 'http://www.wikidata.org/prop/direct/P1365'), ('name', 'replaces')]
# [('p', 'http://www.wikidata.org/prop/direct/P1365'), ('name', 'replaces')]
# [('p', 'http://www.wikidata.org/prop/direct/P1365'), ('name', 'replaces')]
# [('p', 'http://www.wikidata.org/prop/direct/P138'), ('name', 'named after')]
# [('p', 'http://www.wikidata.org/prop/direct/P1417'), ('name', 'Encyclopædia Britannica Online ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1482'), ('name', 'Stack Exchange tag')]
# [('p', 'http://www.wikidata.org/prop/direct/P154'), ('name', 'logo image')]
# [('p', 'http://www.wikidata.org/prop/direct/P166'), ('name', 'award received')]
# [('p', 'http://www.wikidata.org/prop/direct/P17'), ('name', 'country')]
# [('p', 'http://www.wikidata.org/prop/direct/P17'), ('name', 'country')]
# [('p', 'http://www.wikidata.org/prop/direct/P17'), ('name', 'country')]
# [('p', 'http://www.wikidata.org/prop/direct/P17'), ('name', 'country')]
# [('p', 'http://www.wikidata.org/prop/direct/P17'), ('name', 'country')]
# [('p', 'http://www.wikidata.org/prop/direct/P17'), ('name', 'country')]
# [('p', 'http://www.wikidata.org/prop/direct/P17'), ('name', 'country')]
# [('p', 'http://www.wikidata.org/prop/direct/P17'), ('name', 'country')]
# [('p', 'http://www.wikidata.org/prop/direct/P17'), ('name', 'country')]
# [('p', 'http://www.wikidata.org/prop/direct/P17'), ('name', 'country')]
# [('p', 'http://www.wikidata.org/prop/direct/P17'), ('name', 'country')]
# [('p', 'http://www.wikidata.org/prop/direct/P17'), ('name', 'country')]
# [('p', 'http://www.wikidata.org/prop/direct/P17'), ('name', 'country')]
# [('p', 'http://www.wikidata.org/prop/direct/P17'), ('name', 'country')]
# [('p', 'http://www.wikidata.org/prop/direct/P17'), ('name', 'country')]
# [('p', 'http://www.wikidata.org/prop/direct/P17'), ('name', 'country')]
# [('p', 'http://www.wikidata.org/prop/direct/P17'), ('name', 'country')]
# [('p', 'http://www.wikidata.org/prop/direct/P17'), ('name', 'country')]
# [('p', 'http://www.wikidata.org/prop/direct/P17'), ('name', 'country')]
# [('p', 'http://www.wikidata.org/prop/direct/P17'), ('name', 'country')]
# [('p', 'http://www.wikidata.org/prop/direct/P17'), ('name', 'country')]
# [('p', 'http://www.wikidata.org/prop/direct/P17'), ('name', 'country')]
# [('p', 'http://www.wikidata.org/prop/direct/P17'), ('name', 'country')]
# [('p', 'http://www.wikidata.org/prop/direct/P18'), ('name', 'image')]
# [('p', 'http://www.wikidata.org/prop/direct/P1813'), ('name', 'short name')]
# [('p', 'http://www.wikidata.org/prop/direct/P1889'), ('name', 'different from')]
# [('p', 'http://www.wikidata.org/prop/direct/P1993'), ('name', 'TeX string')]
# [('p', 'http://www.wikidata.org/prop/direct/P1993'), ('name', 'TeX string')]
# [('p', 'http://www.wikidata.org/prop/direct/P1993'), ('name', 'TeX string')]
# [('p', 'http://www.wikidata.org/prop/direct/P227'), ('name', 'GND ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2284'), ('name', 'price')]
# [('p', 'http://www.wikidata.org/prop/direct/P2284'), ('name', 'price')]
# [('p', 'http://www.wikidata.org/prop/direct/P2284'), ('name', 'price')]
# [('p', 'http://www.wikidata.org/prop/direct/P2284'), ('name', 'price')]
# [('p', 'http://www.wikidata.org/prop/direct/P2284'), ('name', 'price')]
# [('p', 'http://www.wikidata.org/prop/direct/P2284'), ('name', 'price')]
# [('p', 'http://www.wikidata.org/prop/direct/P2347'), ('name', 'YSO ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P244'), ('name', 'Library of Congress authority ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2442'), ('name', 'conversion to standard unit')]
# [('p', 'http://www.wikidata.org/prop/direct/P2442'), ('name', 'conversion to standard unit')]
# [('p', 'http://www.wikidata.org/prop/direct/P268'), ('name', 'Bibliothèque nationale de France ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('name', 'subclass of')]
# [('p', 'http://www.wikidata.org/prop/direct/P2888'), ('name', 'exact match')]
# [('p', 'http://www.wikidata.org/prop/direct/P2924'), ('name', 'Great Russian Encyclopedia Online ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2959'), ('name', 'permanent duplicated item')]
# [('p', 'http://www.wikidata.org/prop/direct/P2968'), ('name', 'QUDT unit ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('name', 'instance of')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('name', 'instance of')]
# [('p', 'http://www.wikidata.org/prop/direct/P3219'), ('name', 'Encyclopædia Universalis ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3219'), ('name', 'Encyclopædia Universalis ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3347'), ('name', 'PermID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3417'), ('name', 'Quora topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P349'), ('name', 'National Diet Library ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3553'), ('name', 'Zhihu topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3569'), ('name', 'Cultureel Woordenboek ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P373'), ('name', 'Commons category')]
# [('p', 'http://www.wikidata.org/prop/direct/P3911'), ('name', 'STW Thesaurus for Economics ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P4527'), ('name', 'UK Parliament thesaurus ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P487'), ('name', 'Unicode character')]
# [('p', 'http://www.wikidata.org/prop/direct/P489'), ('name', 'currency symbol description')]
# [('p', 'http://www.wikidata.org/prop/direct/P498'), ('name', 'ISO 4217 code')]
# [('p', 'http://www.wikidata.org/prop/direct/P5008'), ('name', 'on focus list of Wikimedia project')]
# [('p', 'http://www.wikidata.org/prop/direct/P5019'), ('name', 'Brockhaus Enzyklopädie online ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P508'), ('name', 'BNCF Thesaurus ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5437'), ('name', 'EuroVoc ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P562'), ('name', 'central bank/issuer')]
# [('p', 'http://www.wikidata.org/prop/direct/P580'), ('name', 'start time')]
# [('p', 'http://www.wikidata.org/prop/direct/P6058'), ('name', 'Larousse ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6404'), ('name', "Treccani's Dizionario di Storia ID")]
# 100

# %%
#return currencies replaced by Euro
queryString = """
SELECT ?obj ?name
WHERE {
   wd:Q4916 wdt:P1365 ?obj.
   # get the label
   # ?obj sc:name ?name.
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('obj', 'http://www.wikidata.org/entity/Q16068'), ('name', 'Deutsche Mark')]
# [('obj', 'http://www.wikidata.org/entity/Q788472'), ('name', 'Dutch guilder')]
# [('obj', 'http://www.wikidata.org/entity/Q203354'), ('name', 'Finnish markka')]
# [('obj', 'http://www.wikidata.org/entity/Q270642'), ('name', 'Irish pound')]
# [('obj', 'http://www.wikidata.org/entity/Q184172'), ('name', 'French franc')]
# [('obj', 'http://www.wikidata.org/entity/Q189097'), ('name', 'peseta')]
# [('obj', 'http://www.wikidata.org/entity/Q204992'), ('name', 'Italian lira')]
# [('obj', 'http://www.wikidata.org/entity/Q468474'), ('name', 'Portuguese escudo')]
# [('obj', 'http://www.wikidata.org/entity/Q1546443'), ('name', 'Greek drachma')]
# [('obj', 'http://www.wikidata.org/entity/Q133011'), ('name', 'Latvian lats')]
# [('obj', 'http://www.wikidata.org/entity/Q174467'), ('name', 'Maltese lira')]
# [('obj', 'http://www.wikidata.org/entity/Q183354'), ('name', 'Vatican lira')]
# [('obj', 'http://www.wikidata.org/entity/Q129983'), ('name', 'Estonian kroon')]
# [('obj', 'http://www.wikidata.org/entity/Q213940'), ('name', 'Luxembourg franc')]
# [('obj', 'http://www.wikidata.org/entity/Q25627'), ('name', 'Lithuanian litas')]
# [('obj', 'http://www.wikidata.org/entity/Q221828'), ('name', 'European Currency Unit')]
# [('obj', 'http://www.wikidata.org/entity/Q193716'), ('name', 'Cypriot pound')]
# [('obj', 'http://www.wikidata.org/entity/Q232415'), ('name', 'Belgian franc')]
# [('obj', 'http://www.wikidata.org/entity/Q178874'), ('name', 'Slovak koruna')]
# [('obj', 'http://www.wikidata.org/entity/Q208730'), ('name', 'Austrian schilling')]
# [('obj', 'http://www.wikidata.org/entity/Q1047040'), ('name', 'Monegasque franc')]
# [('obj', 'http://www.wikidata.org/entity/Q1063029'), ('name', 'Sammarinese lira')]
# [('obj', 'http://www.wikidata.org/entity/Q208133'), ('name', 'Slovenian tolar')]
# 23

# %%
#return properties for Italian lira
queryString = """
SELECT ?p ?name
WHERE {
   wd:Q204992 ?p ?o.
   # get the label
   # ?p sc:name ?name.
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P1001'), ('name', 'applies to jurisdiction')]
# [('p', 'http://www.wikidata.org/prop/direct/P1343'), ('name', 'described by source')]
# [('p', 'http://www.wikidata.org/prop/direct/P1365'), ('name', 'replaces')]
# [('p', 'http://www.wikidata.org/prop/direct/P1365'), ('name', 'replaces')]
# [('p', 'http://www.wikidata.org/prop/direct/P1365'), ('name', 'replaces')]
# [('p', 'http://www.wikidata.org/prop/direct/P1365'), ('name', 'replaces')]
# [('p', 'http://www.wikidata.org/prop/direct/P1365'), ('name', 'replaces')]
# [('p', 'http://www.wikidata.org/prop/direct/P1366'), ('name', 'replaced by')]
# [('p', 'http://www.wikidata.org/prop/direct/P17'), ('name', 'country')]
# [('p', 'http://www.wikidata.org/prop/direct/P17'), ('name', 'country')]
# [('p', 'http://www.wikidata.org/prop/direct/P176'), ('name', 'manufacturer')]
# [('p', 'http://www.wikidata.org/prop/direct/P18'), ('name', 'image')]
# [('p', 'http://www.wikidata.org/prop/direct/P227'), ('name', 'GND ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2284'), ('name', 'price')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('name', 'instance of')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('name', 'instance of')]
# [('p', 'http://www.wikidata.org/prop/direct/P3347'), ('name', 'PermID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3417'), ('name', 'Quora topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P373'), ('name', 'Commons category')]
# [('p', 'http://www.wikidata.org/prop/direct/P489'), ('name', 'currency symbol description')]
# [('p', 'http://www.wikidata.org/prop/direct/P498'), ('name', 'ISO 4217 code')]
# [('p', 'http://www.wikidata.org/prop/direct/P5061'), ('name', 'unit symbol')]
# [('p', 'http://www.wikidata.org/prop/direct/P5061'), ('name', 'unit symbol')]
# [('p', 'http://www.wikidata.org/prop/direct/P508'), ('name', 'BNCF Thesaurus ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P562'), ('name', 'central bank/issuer')]
# [('p', 'http://www.wikidata.org/prop/direct/P580'), ('name', 'start time')]
# [('p', 'http://www.wikidata.org/prop/direct/P582'), ('name', 'end time')]
# [('p', 'http://www.wikidata.org/prop/direct/P646'), ('name', 'Freebase ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7007'), ('name', 'Wolfram Language unit code')]
# [('p', 'http://www.wikidata.org/prop/direct/P910'), ('name', "topic's main category")]
# [('p', 'http://www.wikidata.org/prop/direct/P913'), ('name', 'notation')]
# 31

# %%
#return what Italian lira is instance of
queryString = """
SELECT ?o ?name
WHERE {
   wd:Q204992 wdt:P31 ?o.
   # get the label
   # ?o sc:name ?name.
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('o', 'http://www.wikidata.org/entity/Q28783456'), ('name', 'obsolete currency')]
# [('o', 'http://www.wikidata.org/entity/Q7995739'), ('name', 'lira')]
# 2

# %%
#return country for Italian lira
queryString = """
SELECT ?o ?name
WHERE {
   wd:Q204992 wdt:P17 ?o.
   # get the label
   # ?o sc:name ?name.
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('o', 'http://www.wikidata.org/entity/Q172579'), ('name', 'Kingdom of Italy')]
# [('o', 'http://www.wikidata.org/entity/Q38'), ('name', 'Italy')]
# 2

# %%
#return what italian lira is replaced by
queryString = """
SELECT ?o ?name
WHERE {
   wd:Q204992 wdt:P1366 ?o.
   # get the label
   # ?o sc:name ?name.
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('o', 'http://www.wikidata.org/entity/Q4916'), ('name', 'euro')]
# 1

# %%
#final query try
queryString = """
SELECT ?country ?cName ?previousCurrency ?currName
WHERE {
   # ?country wdt:P31 wd:Q6256;
            wdt:P38 wd:Q4916.
   # ?previousCurrency wdt:P1366 wd:Q4916;
                     wdt:P17 ?country.
   
   # get the label
   # ?country sc:name ?cName.
   # ?previousCurrency sc:name ?currName
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('country', 'http://www.wikidata.org/entity/Q142'), ('cName', 'France'), ('previousCurrency', 'http://www.wikidata.org/entity/Q184172'), ('currName', 'French franc')]
# [('country', 'http://www.wikidata.org/entity/Q211'), ('cName', 'Latvia'), ('previousCurrency', 'http://www.wikidata.org/entity/Q133011'), ('currName', 'Latvian lats')]
# [('country', 'http://www.wikidata.org/entity/Q214'), ('cName', 'Slovakia'), ('previousCurrency', 'http://www.wikidata.org/entity/Q178874'), ('currName', 'Slovak koruna')]
# [('country', 'http://www.wikidata.org/entity/Q228'), ('cName', 'Andorra'), ('previousCurrency', 'http://www.wikidata.org/entity/Q184172'), ('currName', 'French franc')]
# [('country', 'http://www.wikidata.org/entity/Q228'), ('cName', 'Andorra'), ('previousCurrency', 'http://www.wikidata.org/entity/Q189097'), ('currName', 'peseta')]
# [('country', 'http://www.wikidata.org/entity/Q229'), ('cName', 'Cyprus'), ('previousCurrency', 'http://www.wikidata.org/entity/Q193716'), ('currName', 'Cypriot pound')]
# [('country', 'http://www.wikidata.org/entity/Q233'), ('cName', 'Malta'), ('previousCurrency', 'http://www.wikidata.org/entity/Q174467'), ('currName', 'Maltese lira')]
# [('country', 'http://www.wikidata.org/entity/Q27'), ('cName', 'Ireland'), ('previousCurrency', 'http://www.wikidata.org/entity/Q270642'), ('currName', 'Irish pound')]
# [('country', 'http://www.wikidata.org/entity/Q29999'), ('cName', 'Kingdom of the Netherlands'), ('previousCurrency', 'http://www.wikidata.org/entity/Q788472'), ('currName', 'Dutch guilder')]
# [('country', 'http://www.wikidata.org/entity/Q33'), ('cName', 'Finland'), ('previousCurrency', 'http://www.wikidata.org/entity/Q203354'), ('currName', 'Finnish markka')]
# [('country', 'http://www.wikidata.org/entity/Q38'), ('cName', 'Italy'), ('previousCurrency', 'http://www.wikidata.org/entity/Q204992'), ('currName', 'Italian lira')]
# [('country', 'http://www.wikidata.org/entity/Q40'), ('cName', 'Austria'), ('previousCurrency', 'http://www.wikidata.org/entity/Q208730'), ('currName', 'Austrian schilling')]
# [('country', 'http://www.wikidata.org/entity/Q41'), ('cName', 'Greece'), ('previousCurrency', 'http://www.wikidata.org/entity/Q1546443'), ('currName', 'Greek drachma')]
# [('country', 'http://www.wikidata.org/entity/Q45'), ('cName', 'Portugal'), ('previousCurrency', 'http://www.wikidata.org/entity/Q468474'), ('currName', 'Portuguese escudo')]
# 14

# %%
#return properties linking Italy and Italian lira
queryString = """
SELECT ?p ?name
WHERE {
   wd:Q38 ?p wd:Q204992.
   # get the label
   # ?p sc:name ?name
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# Empty

# %%
#return properties linking Italian lira and Italy
queryString = """
SELECT ?p ?name
WHERE {
   wd:Q204992 ?p wd:Q38.
   # get the label
   # ?p sc:name ?name
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P1001'), ('name', 'applies to jurisdiction')]
# [('p', 'http://www.wikidata.org/prop/direct/P17'), ('name', 'country')]
# 2

# %%
#return country for Italian lira
queryString = """
SELECT ?o ?name
WHERE {
   wd:Q204992 wdt:P17 ?o.
   # get the label
   # ?o sc:name ?name
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('o', 'http://www.wikidata.org/entity/Q172579'), ('name', 'Kingdom of Italy')]
# [('o', 'http://www.wikidata.org/entity/Q38'), ('name', 'Italy')]
# 2

# %%
#search for previous currency for Montenegro
queryString = """
SELECT ?country ?cName ?previousCurrency ?currName
WHERE {
   # ?previousCurrency wdt:P1366 wd:Q4916;
                     wdt:P17|wdt:P1001 wd:Q236.
   
   # get the label
   # ?country sc:name ?cName.
   # ?previousCurrency sc:name ?currName
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# Empty

# %%
#For each country that now uses Euro return which was the currencies used before
queryString = """
SELECT ?country ?cName ?previousCurrency ?currName
WHERE {
   # ?country wdt:P31 wd:Q6256;
            wdt:P38 wd:Q4916.
   # ?previousCurrency wdt:P1366 wd:Q4916;
                     wdt:P17 ?country.
   
   # get the label
   # ?country sc:name ?cName.
   # ?previousCurrency sc:name ?currName
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('country', 'http://www.wikidata.org/entity/Q142'), ('cName', 'France'), ('previousCurrency', 'http://www.wikidata.org/entity/Q184172'), ('currName', 'French franc')]
# [('country', 'http://www.wikidata.org/entity/Q211'), ('cName', 'Latvia'), ('previousCurrency', 'http://www.wikidata.org/entity/Q133011'), ('currName', 'Latvian lats')]
# [('country', 'http://www.wikidata.org/entity/Q214'), ('cName', 'Slovakia'), ('previousCurrency', 'http://www.wikidata.org/entity/Q178874'), ('currName', 'Slovak koruna')]
# [('country', 'http://www.wikidata.org/entity/Q228'), ('cName', 'Andorra'), ('previousCurrency', 'http://www.wikidata.org/entity/Q184172'), ('currName', 'French franc')]
# [('country', 'http://www.wikidata.org/entity/Q228'), ('cName', 'Andorra'), ('previousCurrency', 'http://www.wikidata.org/entity/Q189097'), ('currName', 'peseta')]
# [('country', 'http://www.wikidata.org/entity/Q229'), ('cName', 'Cyprus'), ('previousCurrency', 'http://www.wikidata.org/entity/Q193716'), ('currName', 'Cypriot pound')]
# [('country', 'http://www.wikidata.org/entity/Q233'), ('cName', 'Malta'), ('previousCurrency', 'http://www.wikidata.org/entity/Q174467'), ('currName', 'Maltese lira')]
# [('country', 'http://www.wikidata.org/entity/Q27'), ('cName', 'Ireland'), ('previousCurrency', 'http://www.wikidata.org/entity/Q270642'), ('currName', 'Irish pound')]
# [('country', 'http://www.wikidata.org/entity/Q29999'), ('cName', 'Kingdom of the Netherlands'), ('previousCurrency', 'http://www.wikidata.org/entity/Q788472'), ('currName', 'Dutch guilder')]
# [('country', 'http://www.wikidata.org/entity/Q33'), ('cName', 'Finland'), ('previousCurrency', 'http://www.wikidata.org/entity/Q203354'), ('currName', 'Finnish markka')]
# [('country', 'http://www.wikidata.org/entity/Q38'), ('cName', 'Italy'), ('previousCurrency', 'http://www.wikidata.org/entity/Q204992'), ('currName', 'Italian lira')]
# [('country', 'http://www.wikidata.org/entity/Q40'), ('cName', 'Austria'), ('previousCurrency', 'http://www.wikidata.org/entity/Q208730'), ('currName', 'Austrian schilling')]
# [('country', 'http://www.wikidata.org/entity/Q41'), ('cName', 'Greece'), ('previousCurrency', 'http://www.wikidata.org/entity/Q1546443'), ('currName', 'Greek drachma')]
# [('country', 'http://www.wikidata.org/entity/Q45'), ('cName', 'Portugal'), ('previousCurrency', 'http://www.wikidata.org/entity/Q468474'), ('currName', 'Portuguese escudo')]
# 14

# %%
#For each country (with * operator) that now uses Euro return which was the currencies used before
queryString = """
SELECT DISTINCT ?country ?cName ?previousCurrency ?currName
WHERE {
   # ?country wdt:P31 ?class;
            wdt:P38 wd:Q4916.
   # ?class wdt:P279* wd:Q6256.
   # ?previousCurrency wdt:P1366 wd:Q4916;
                     wdt:P17 ?country.
   
   # get the label
   # ?country sc:name ?cName.
   # ?previousCurrency sc:name ?currName
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('country', 'http://www.wikidata.org/entity/Q183'), ('cName', 'Germany'), ('previousCurrency', 'http://www.wikidata.org/entity/Q16068'), ('currName', 'Deutsche Mark')]
# [('country', 'http://www.wikidata.org/entity/Q29999'), ('cName', 'Kingdom of the Netherlands'), ('previousCurrency', 'http://www.wikidata.org/entity/Q788472'), ('currName', 'Dutch guilder')]
# [('country', 'http://www.wikidata.org/entity/Q33'), ('cName', 'Finland'), ('previousCurrency', 'http://www.wikidata.org/entity/Q203354'), ('currName', 'Finnish markka')]
# [('country', 'http://www.wikidata.org/entity/Q27'), ('cName', 'Ireland'), ('previousCurrency', 'http://www.wikidata.org/entity/Q270642'), ('currName', 'Irish pound')]
# [('country', 'http://www.wikidata.org/entity/Q142'), ('cName', 'France'), ('previousCurrency', 'http://www.wikidata.org/entity/Q184172'), ('currName', 'French franc')]
# [('country', 'http://www.wikidata.org/entity/Q228'), ('cName', 'Andorra'), ('previousCurrency', 'http://www.wikidata.org/entity/Q184172'), ('currName', 'French franc')]
# [('country', 'http://www.wikidata.org/entity/Q235'), ('cName', 'Monaco'), ('previousCurrency', 'http://www.wikidata.org/entity/Q184172'), ('currName', 'French franc')]
# [('country', 'http://www.wikidata.org/entity/Q228'), ('cName', 'Andorra'), ('previousCurrency', 'http://www.wikidata.org/entity/Q189097'), ('currName', 'peseta')]
# [('country', 'http://www.wikidata.org/entity/Q29'), ('cName', 'Spain'), ('previousCurrency', 'http://www.wikidata.org/entity/Q189097'), ('currName', 'peseta')]
# [('country', 'http://www.wikidata.org/entity/Q38'), ('cName', 'Italy'), ('previousCurrency', 'http://www.wikidata.org/entity/Q204992'), ('currName', 'Italian lira')]
# [('country', 'http://www.wikidata.org/entity/Q45'), ('cName', 'Portugal'), ('previousCurrency', 'http://www.wikidata.org/entity/Q468474'), ('currName', 'Portuguese escudo')]
# [('country', 'http://www.wikidata.org/entity/Q41'), ('cName', 'Greece'), ('previousCurrency', 'http://www.wikidata.org/entity/Q1546443'), ('currName', 'Greek drachma')]
# [('country', 'http://www.wikidata.org/entity/Q211'), ('cName', 'Latvia'), ('previousCurrency', 'http://www.wikidata.org/entity/Q133011'), ('currName', 'Latvian lats')]
# [('country', 'http://www.wikidata.org/entity/Q233'), ('cName', 'Malta'), ('previousCurrency', 'http://www.wikidata.org/entity/Q174467'), ('currName', 'Maltese lira')]
# [('country', 'http://www.wikidata.org/entity/Q237'), ('cName', 'Vatican City'), ('previousCurrency', 'http://www.wikidata.org/entity/Q183354'), ('currName', 'Vatican lira')]
# [('country', 'http://www.wikidata.org/entity/Q191'), ('cName', 'Estonia'), ('previousCurrency', 'http://www.wikidata.org/entity/Q129983'), ('currName', 'Estonian kroon')]
# [('country', 'http://www.wikidata.org/entity/Q32'), ('cName', 'Luxembourg'), ('previousCurrency', 'http://www.wikidata.org/entity/Q213940'), ('currName', 'Luxembourg franc')]
# [('country', 'http://www.wikidata.org/entity/Q37'), ('cName', 'Lithuania'), ('previousCurrency', 'http://www.wikidata.org/entity/Q25627'), ('currName', 'Lithuanian litas')]
# [('country', 'http://www.wikidata.org/entity/Q229'), ('cName', 'Cyprus'), ('previousCurrency', 'http://www.wikidata.org/entity/Q193716'), ('currName', 'Cypriot pound')]
# [('country', 'http://www.wikidata.org/entity/Q31'), ('cName', 'Belgium'), ('previousCurrency', 'http://www.wikidata.org/entity/Q232415'), ('currName', 'Belgian franc')]
# [('country', 'http://www.wikidata.org/entity/Q214'), ('cName', 'Slovakia'), ('previousCurrency', 'http://www.wikidata.org/entity/Q178874'), ('currName', 'Slovak koruna')]
# [('country', 'http://www.wikidata.org/entity/Q40'), ('cName', 'Austria'), ('previousCurrency', 'http://www.wikidata.org/entity/Q208730'), ('currName', 'Austrian schilling')]
# [('country', 'http://www.wikidata.org/entity/Q235'), ('cName', 'Monaco'), ('previousCurrency', 'http://www.wikidata.org/entity/Q1047040'), ('currName', 'Monegasque franc')]
# [('country', 'http://www.wikidata.org/entity/Q238'), ('cName', 'San Marino'), ('previousCurrency', 'http://www.wikidata.org/entity/Q1063029'), ('currName', 'Sammarinese lira')]
# [('country', 'http://www.wikidata.org/entity/Q215'), ('cName', 'Slovenia'), ('previousCurrency', 'http://www.wikidata.org/entity/Q208133'), ('currName', 'Slovenian tolar')]
# 25

# %%
#For each country (with + operator) that now uses Euro return which was the currencies used before
queryString = """
SELECT DISTINCT ?country ?cName ?previousCurrency ?currName
WHERE {
   # ?country wdt:P31 ?class;
            wdt:P38 wd:Q4916.
   # ?class wdt:P279+ wd:Q6256.
   # ?previousCurrency wdt:P1366 wd:Q4916;
                     wdt:P17 ?country.
   
   # get the label
   # ?country sc:name ?cName.
   # ?previousCurrency sc:name ?currName
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('country', 'http://www.wikidata.org/entity/Q183'), ('cName', 'Germany'), ('previousCurrency', 'http://www.wikidata.org/entity/Q16068'), ('currName', 'Deutsche Mark')]
# [('country', 'http://www.wikidata.org/entity/Q29999'), ('cName', 'Kingdom of the Netherlands'), ('previousCurrency', 'http://www.wikidata.org/entity/Q788472'), ('currName', 'Dutch guilder')]
# [('country', 'http://www.wikidata.org/entity/Q33'), ('cName', 'Finland'), ('previousCurrency', 'http://www.wikidata.org/entity/Q203354'), ('currName', 'Finnish markka')]
# [('country', 'http://www.wikidata.org/entity/Q27'), ('cName', 'Ireland'), ('previousCurrency', 'http://www.wikidata.org/entity/Q270642'), ('currName', 'Irish pound')]
# [('country', 'http://www.wikidata.org/entity/Q142'), ('cName', 'France'), ('previousCurrency', 'http://www.wikidata.org/entity/Q184172'), ('currName', 'French franc')]
# [('country', 'http://www.wikidata.org/entity/Q228'), ('cName', 'Andorra'), ('previousCurrency', 'http://www.wikidata.org/entity/Q184172'), ('currName', 'French franc')]
# [('country', 'http://www.wikidata.org/entity/Q235'), ('cName', 'Monaco'), ('previousCurrency', 'http://www.wikidata.org/entity/Q184172'), ('currName', 'French franc')]
# [('country', 'http://www.wikidata.org/entity/Q228'), ('cName', 'Andorra'), ('previousCurrency', 'http://www.wikidata.org/entity/Q189097'), ('currName', 'peseta')]
# [('country', 'http://www.wikidata.org/entity/Q29'), ('cName', 'Spain'), ('previousCurrency', 'http://www.wikidata.org/entity/Q189097'), ('currName', 'peseta')]
# [('country', 'http://www.wikidata.org/entity/Q38'), ('cName', 'Italy'), ('previousCurrency', 'http://www.wikidata.org/entity/Q204992'), ('currName', 'Italian lira')]
# [('country', 'http://www.wikidata.org/entity/Q45'), ('cName', 'Portugal'), ('previousCurrency', 'http://www.wikidata.org/entity/Q468474'), ('currName', 'Portuguese escudo')]
# [('country', 'http://www.wikidata.org/entity/Q41'), ('cName', 'Greece'), ('previousCurrency', 'http://www.wikidata.org/entity/Q1546443'), ('currName', 'Greek drachma')]
# [('country', 'http://www.wikidata.org/entity/Q211'), ('cName', 'Latvia'), ('previousCurrency', 'http://www.wikidata.org/entity/Q133011'), ('currName', 'Latvian lats')]
# [('country', 'http://www.wikidata.org/entity/Q233'), ('cName', 'Malta'), ('previousCurrency', 'http://www.wikidata.org/entity/Q174467'), ('currName', 'Maltese lira')]
# [('country', 'http://www.wikidata.org/entity/Q237'), ('cName', 'Vatican City'), ('previousCurrency', 'http://www.wikidata.org/entity/Q183354'), ('currName', 'Vatican lira')]
# [('country', 'http://www.wikidata.org/entity/Q191'), ('cName', 'Estonia'), ('previousCurrency', 'http://www.wikidata.org/entity/Q129983'), ('currName', 'Estonian kroon')]
# [('country', 'http://www.wikidata.org/entity/Q32'), ('cName', 'Luxembourg'), ('previousCurrency', 'http://www.wikidata.org/entity/Q213940'), ('currName', 'Luxembourg franc')]
# [('country', 'http://www.wikidata.org/entity/Q37'), ('cName', 'Lithuania'), ('previousCurrency', 'http://www.wikidata.org/entity/Q25627'), ('currName', 'Lithuanian litas')]
# [('country', 'http://www.wikidata.org/entity/Q229'), ('cName', 'Cyprus'), ('previousCurrency', 'http://www.wikidata.org/entity/Q193716'), ('currName', 'Cypriot pound')]
# [('country', 'http://www.wikidata.org/entity/Q31'), ('cName', 'Belgium'), ('previousCurrency', 'http://www.wikidata.org/entity/Q232415'), ('currName', 'Belgian franc')]
# [('country', 'http://www.wikidata.org/entity/Q214'), ('cName', 'Slovakia'), ('previousCurrency', 'http://www.wikidata.org/entity/Q178874'), ('currName', 'Slovak koruna')]
# [('country', 'http://www.wikidata.org/entity/Q40'), ('cName', 'Austria'), ('previousCurrency', 'http://www.wikidata.org/entity/Q208730'), ('currName', 'Austrian schilling')]
# [('country', 'http://www.wikidata.org/entity/Q235'), ('cName', 'Monaco'), ('previousCurrency', 'http://www.wikidata.org/entity/Q1047040'), ('currName', 'Monegasque franc')]
# [('country', 'http://www.wikidata.org/entity/Q238'), ('cName', 'San Marino'), ('previousCurrency', 'http://www.wikidata.org/entity/Q1063029'), ('currName', 'Sammarinese lira')]
# [('country', 'http://www.wikidata.org/entity/Q215'), ('cName', 'Slovenia'), ('previousCurrency', 'http://www.wikidata.org/entity/Q208133'), ('currName', 'Slovenian tolar')]
# 25

# %%
#For each country (with * operator) that now uses Euro return which was the currencies used before
queryString = """
SELECT DISTINCT ?country ?cName ?previousCurrency ?currName
WHERE {
   # ?country wdt:P31 ?class;
            wdt:P38 wd:Q4916.
   # ?class wdt:P279* wd:Q6256.
   # ?previousCurrency wdt:P1366 wd:Q4916.
   # ?country wdt:P38 ?previousCurrency.
   
   # get the label
   # ?country sc:name ?cName.
   # ?previousCurrency sc:name ?currName
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# Empty

# %%
#For each country (with * operator) that now uses Euro return which was the currencies used before with optional previous currency
queryString = """
SELECT DISTINCT ?country ?cName ?previousCurrency ?currName
WHERE {
   # ?country wdt:P31 ?class;
            wdt:P38 wd:Q4916.
   # ?class wdt:P279* wd:Q6256.
   OPTIONAL{?previousCurrency wdt:P1366 wd:Q4916;
                     wdt:P17 ?country;
                     sc:name ?currName.}            
   
   # get the label
   # ?country sc:name ?cName.
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('country', 'http://www.wikidata.org/entity/Q142'), ('cName', 'France'), ('previousCurrency', 'http://www.wikidata.org/entity/Q184172'), ('currName', 'French franc')]
# [('country', 'http://www.wikidata.org/entity/Q183'), ('cName', 'Germany'), ('previousCurrency', 'http://www.wikidata.org/entity/Q16068'), ('currName', 'Deutsche Mark')]
# [('country', 'http://www.wikidata.org/entity/Q191'), ('cName', 'Estonia'), ('previousCurrency', 'http://www.wikidata.org/entity/Q129983'), ('currName', 'Estonian kroon')]
# [('country', 'http://www.wikidata.org/entity/Q211'), ('cName', 'Latvia'), ('previousCurrency', 'http://www.wikidata.org/entity/Q133011'), ('currName', 'Latvian lats')]
# [('country', 'http://www.wikidata.org/entity/Q214'), ('cName', 'Slovakia'), ('previousCurrency', 'http://www.wikidata.org/entity/Q178874'), ('currName', 'Slovak koruna')]
# [('country', 'http://www.wikidata.org/entity/Q215'), ('cName', 'Slovenia'), ('previousCurrency', 'http://www.wikidata.org/entity/Q208133'), ('currName', 'Slovenian tolar')]
# [('country', 'http://www.wikidata.org/entity/Q228'), ('cName', 'Andorra'), ('previousCurrency', 'http://www.wikidata.org/entity/Q184172'), ('currName', 'French franc')]
# [('country', 'http://www.wikidata.org/entity/Q228'), ('cName', 'Andorra'), ('previousCurrency', 'http://www.wikidata.org/entity/Q189097'), ('currName', 'peseta')]
# [('country', 'http://www.wikidata.org/entity/Q229'), ('cName', 'Cyprus'), ('previousCurrency', 'http://www.wikidata.org/entity/Q193716'), ('currName', 'Cypriot pound')]
# [('country', 'http://www.wikidata.org/entity/Q233'), ('cName', 'Malta'), ('previousCurrency', 'http://www.wikidata.org/entity/Q174467'), ('currName', 'Maltese lira')]
# [('country', 'http://www.wikidata.org/entity/Q235'), ('cName', 'Monaco'), ('previousCurrency', 'http://www.wikidata.org/entity/Q184172'), ('currName', 'French franc')]
# [('country', 'http://www.wikidata.org/entity/Q235'), ('cName', 'Monaco'), ('previousCurrency', 'http://www.wikidata.org/entity/Q1047040'), ('currName', 'Monegasque franc')]
# [('country', 'http://www.wikidata.org/entity/Q237'), ('cName', 'Vatican City'), ('previousCurrency', 'http://www.wikidata.org/entity/Q183354'), ('currName', 'Vatican lira')]
# [('country', 'http://www.wikidata.org/entity/Q238'), ('cName', 'San Marino'), ('previousCurrency', 'http://www.wikidata.org/entity/Q1063029'), ('currName', 'Sammarinese lira')]
# [('country', 'http://www.wikidata.org/entity/Q27'), ('cName', 'Ireland'), ('previousCurrency', 'http://www.wikidata.org/entity/Q270642'), ('currName', 'Irish pound')]
# [('country', 'http://www.wikidata.org/entity/Q29'), ('cName', 'Spain'), ('previousCurrency', 'http://www.wikidata.org/entity/Q189097'), ('currName', 'peseta')]
# [('country', 'http://www.wikidata.org/entity/Q29999'), ('cName', 'Kingdom of the Netherlands'), ('previousCurrency', 'http://www.wikidata.org/entity/Q788472'), ('currName', 'Dutch guilder')]
# [('country', 'http://www.wikidata.org/entity/Q31'), ('cName', 'Belgium'), ('previousCurrency', 'http://www.wikidata.org/entity/Q232415'), ('currName', 'Belgian franc')]
# [('country', 'http://www.wikidata.org/entity/Q32'), ('cName', 'Luxembourg'), ('previousCurrency', 'http://www.wikidata.org/entity/Q213940'), ('currName', 'Luxembourg franc')]
# [('country', 'http://www.wikidata.org/entity/Q33'), ('cName', 'Finland'), ('previousCurrency', 'http://www.wikidata.org/entity/Q203354'), ('currName', 'Finnish markka')]
# [('country', 'http://www.wikidata.org/entity/Q37'), ('cName', 'Lithuania'), ('previousCurrency', 'http://www.wikidata.org/entity/Q25627'), ('currName', 'Lithuanian litas')]
# [('country', 'http://www.wikidata.org/entity/Q38'), ('cName', 'Italy'), ('previousCurrency', 'http://www.wikidata.org/entity/Q204992'), ('currName', 'Italian lira')]
# [('country', 'http://www.wikidata.org/entity/Q40'), ('cName', 'Austria'), ('previousCurrency', 'http://www.wikidata.org/entity/Q208730'), ('currName', 'Austrian schilling')]
# [('country', 'http://www.wikidata.org/entity/Q41'), ('cName', 'Greece'), ('previousCurrency', 'http://www.wikidata.org/entity/Q1546443'), ('currName', 'Greek drachma')]
# [('country', 'http://www.wikidata.org/entity/Q45'), ('cName', 'Portugal'), ('previousCurrency', 'http://www.wikidata.org/entity/Q468474'), ('currName', 'Portuguese escudo')]
# [('country', 'http://www.wikidata.org/entity/Q236'), ('cName', 'Montenegro')]
# [('country', 'http://www.wikidata.org/entity/Q236'), ('cName', 'Montenegro')]
# [('country', 'http://www.wikidata.org/entity/Q236'), ('cName', 'Montenegro')]
# [('country', 'http://www.wikidata.org/entity/Q236'), ('cName', 'Montenegro')]
# [('country', 'http://www.wikidata.org/entity/Q55'), ('cName', 'Netherlands')]
# 30

# %%
#For each country that now uses Euro return which were the currencies used before
queryString = """
SELECT DISTINCT ?country ?cName ?previousCurrency ?currName
WHERE {
   # ?country wdt:P31/wdt:P279* wd:Q6256;
            wdt:P38 wd:Q4916.
   # ?previousCurrency wdt:P1366 wd:Q4916;
                     wdt:P17 ?country.
   
   # get the label
   # ?country sc:name ?cName.
   # ?previousCurrency sc:name ?currName
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('country', 'http://www.wikidata.org/entity/Q183'), ('cName', 'Germany'), ('previousCurrency', 'http://www.wikidata.org/entity/Q16068'), ('currName', 'Deutsche Mark')]
# [('country', 'http://www.wikidata.org/entity/Q29999'), ('cName', 'Kingdom of the Netherlands'), ('previousCurrency', 'http://www.wikidata.org/entity/Q788472'), ('currName', 'Dutch guilder')]
# [('country', 'http://www.wikidata.org/entity/Q33'), ('cName', 'Finland'), ('previousCurrency', 'http://www.wikidata.org/entity/Q203354'), ('currName', 'Finnish markka')]
# [('country', 'http://www.wikidata.org/entity/Q27'), ('cName', 'Ireland'), ('previousCurrency', 'http://www.wikidata.org/entity/Q270642'), ('currName', 'Irish pound')]
# [('country', 'http://www.wikidata.org/entity/Q142'), ('cName', 'France'), ('previousCurrency', 'http://www.wikidata.org/entity/Q184172'), ('currName', 'French franc')]
# [('country', 'http://www.wikidata.org/entity/Q228'), ('cName', 'Andorra'), ('previousCurrency', 'http://www.wikidata.org/entity/Q184172'), ('currName', 'French franc')]
# [('country', 'http://www.wikidata.org/entity/Q235'), ('cName', 'Monaco'), ('previousCurrency', 'http://www.wikidata.org/entity/Q184172'), ('currName', 'French franc')]
# [('country', 'http://www.wikidata.org/entity/Q228'), ('cName', 'Andorra'), ('previousCurrency', 'http://www.wikidata.org/entity/Q189097'), ('currName', 'peseta')]
# [('country', 'http://www.wikidata.org/entity/Q29'), ('cName', 'Spain'), ('previousCurrency', 'http://www.wikidata.org/entity/Q189097'), ('currName', 'peseta')]
# [('country', 'http://www.wikidata.org/entity/Q38'), ('cName', 'Italy'), ('previousCurrency', 'http://www.wikidata.org/entity/Q204992'), ('currName', 'Italian lira')]
# [('country', 'http://www.wikidata.org/entity/Q45'), ('cName', 'Portugal'), ('previousCurrency', 'http://www.wikidata.org/entity/Q468474'), ('currName', 'Portuguese escudo')]
# [('country', 'http://www.wikidata.org/entity/Q41'), ('cName', 'Greece'), ('previousCurrency', 'http://www.wikidata.org/entity/Q1546443'), ('currName', 'Greek drachma')]
# [('country', 'http://www.wikidata.org/entity/Q211'), ('cName', 'Latvia'), ('previousCurrency', 'http://www.wikidata.org/entity/Q133011'), ('currName', 'Latvian lats')]
# [('country', 'http://www.wikidata.org/entity/Q233'), ('cName', 'Malta'), ('previousCurrency', 'http://www.wikidata.org/entity/Q174467'), ('currName', 'Maltese lira')]
# [('country', 'http://www.wikidata.org/entity/Q237'), ('cName', 'Vatican City'), ('previousCurrency', 'http://www.wikidata.org/entity/Q183354'), ('currName', 'Vatican lira')]
# [('country', 'http://www.wikidata.org/entity/Q191'), ('cName', 'Estonia'), ('previousCurrency', 'http://www.wikidata.org/entity/Q129983'), ('currName', 'Estonian kroon')]
# [('country', 'http://www.wikidata.org/entity/Q32'), ('cName', 'Luxembourg'), ('previousCurrency', 'http://www.wikidata.org/entity/Q213940'), ('currName', 'Luxembourg franc')]
# [('country', 'http://www.wikidata.org/entity/Q37'), ('cName', 'Lithuania'), ('previousCurrency', 'http://www.wikidata.org/entity/Q25627'), ('currName', 'Lithuanian litas')]
# [('country', 'http://www.wikidata.org/entity/Q229'), ('cName', 'Cyprus'), ('previousCurrency', 'http://www.wikidata.org/entity/Q193716'), ('currName', 'Cypriot pound')]
# [('country', 'http://www.wikidata.org/entity/Q31'), ('cName', 'Belgium'), ('previousCurrency', 'http://www.wikidata.org/entity/Q232415'), ('currName', 'Belgian franc')]
# [('country', 'http://www.wikidata.org/entity/Q214'), ('cName', 'Slovakia'), ('previousCurrency', 'http://www.wikidata.org/entity/Q178874'), ('currName', 'Slovak koruna')]
# [('country', 'http://www.wikidata.org/entity/Q40'), ('cName', 'Austria'), ('previousCurrency', 'http://www.wikidata.org/entity/Q208730'), ('currName', 'Austrian schilling')]
# [('country', 'http://www.wikidata.org/entity/Q235'), ('cName', 'Monaco'), ('previousCurrency', 'http://www.wikidata.org/entity/Q1047040'), ('currName', 'Monegasque franc')]
# [('country', 'http://www.wikidata.org/entity/Q238'), ('cName', 'San Marino'), ('previousCurrency', 'http://www.wikidata.org/entity/Q1063029'), ('currName', 'Sammarinese lira')]
# [('country', 'http://www.wikidata.org/entity/Q215'), ('cName', 'Slovenia'), ('previousCurrency', 'http://www.wikidata.org/entity/Q208133'), ('currName', 'Slovenian tolar')]
# 25

# %% [markdown]
# Final query for this task

# %%
# write your final query
queryString = """
SELECT DISTINCT ?country ?cName ?previousCurrency ?currName
WHERE {
   # ?country wdt:P31/wdt:P279* wd:Q6256;
            wdt:P38 wd:Q4916.
   # ?previousCurrency wdt:P1366 wd:Q4916;
                     wdt:P17 ?country.
   
   # get the label
   # ?country sc:name ?cName.
   # ?previousCurrency sc:name ?currName
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('country', 'http://www.wikidata.org/entity/Q183'), ('cName', 'Germany'), ('previousCurrency', 'http://www.wikidata.org/entity/Q16068'), ('currName', 'Deutsche Mark')]
# [('country', 'http://www.wikidata.org/entity/Q29999'), ('cName', 'Kingdom of the Netherlands'), ('previousCurrency', 'http://www.wikidata.org/entity/Q788472'), ('currName', 'Dutch guilder')]
# [('country', 'http://www.wikidata.org/entity/Q33'), ('cName', 'Finland'), ('previousCurrency', 'http://www.wikidata.org/entity/Q203354'), ('currName', 'Finnish markka')]
# [('country', 'http://www.wikidata.org/entity/Q27'), ('cName', 'Ireland'), ('previousCurrency', 'http://www.wikidata.org/entity/Q270642'), ('currName', 'Irish pound')]
# [('country', 'http://www.wikidata.org/entity/Q142'), ('cName', 'France'), ('previousCurrency', 'http://www.wikidata.org/entity/Q184172'), ('currName', 'French franc')]
# [('country', 'http://www.wikidata.org/entity/Q228'), ('cName', 'Andorra'), ('previousCurrency', 'http://www.wikidata.org/entity/Q184172'), ('currName', 'French franc')]
# [('country', 'http://www.wikidata.org/entity/Q235'), ('cName', 'Monaco'), ('previousCurrency', 'http://www.wikidata.org/entity/Q184172'), ('currName', 'French franc')]
# [('country', 'http://www.wikidata.org/entity/Q228'), ('cName', 'Andorra'), ('previousCurrency', 'http://www.wikidata.org/entity/Q189097'), ('currName', 'peseta')]
# [('country', 'http://www.wikidata.org/entity/Q29'), ('cName', 'Spain'), ('previousCurrency', 'http://www.wikidata.org/entity/Q189097'), ('currName', 'peseta')]
# [('country', 'http://www.wikidata.org/entity/Q38'), ('cName', 'Italy'), ('previousCurrency', 'http://www.wikidata.org/entity/Q204992'), ('currName', 'Italian lira')]
# [('country', 'http://www.wikidata.org/entity/Q45'), ('cName', 'Portugal'), ('previousCurrency', 'http://www.wikidata.org/entity/Q468474'), ('currName', 'Portuguese escudo')]
# [('country', 'http://www.wikidata.org/entity/Q41'), ('cName', 'Greece'), ('previousCurrency', 'http://www.wikidata.org/entity/Q1546443'), ('currName', 'Greek drachma')]
# [('country', 'http://www.wikidata.org/entity/Q211'), ('cName', 'Latvia'), ('previousCurrency', 'http://www.wikidata.org/entity/Q133011'), ('currName', 'Latvian lats')]
# [('country', 'http://www.wikidata.org/entity/Q233'), ('cName', 'Malta'), ('previousCurrency', 'http://www.wikidata.org/entity/Q174467'), ('currName', 'Maltese lira')]
# [('country', 'http://www.wikidata.org/entity/Q237'), ('cName', 'Vatican City'), ('previousCurrency', 'http://www.wikidata.org/entity/Q183354'), ('currName', 'Vatican lira')]
# [('country', 'http://www.wikidata.org/entity/Q191'), ('cName', 'Estonia'), ('previousCurrency', 'http://www.wikidata.org/entity/Q129983'), ('currName', 'Estonian kroon')]
# [('country', 'http://www.wikidata.org/entity/Q32'), ('cName', 'Luxembourg'), ('previousCurrency', 'http://www.wikidata.org/entity/Q213940'), ('currName', 'Luxembourg franc')]
# [('country', 'http://www.wikidata.org/entity/Q37'), ('cName', 'Lithuania'), ('previousCurrency', 'http://www.wikidata.org/entity/Q25627'), ('currName', 'Lithuanian litas')]
# [('country', 'http://www.wikidata.org/entity/Q229'), ('cName', 'Cyprus'), ('previousCurrency', 'http://www.wikidata.org/entity/Q193716'), ('currName', 'Cypriot pound')]
# [('country', 'http://www.wikidata.org/entity/Q31'), ('cName', 'Belgium'), ('previousCurrency', 'http://www.wikidata.org/entity/Q232415'), ('currName', 'Belgian franc')]
# [('country', 'http://www.wikidata.org/entity/Q214'), ('cName', 'Slovakia'), ('previousCurrency', 'http://www.wikidata.org/entity/Q178874'), ('currName', 'Slovak koruna')]
# [('country', 'http://www.wikidata.org/entity/Q40'), ('cName', 'Austria'), ('previousCurrency', 'http://www.wikidata.org/entity/Q208730'), ('currName', 'Austrian schilling')]
# [('country', 'http://www.wikidata.org/entity/Q235'), ('cName', 'Monaco'), ('previousCurrency', 'http://www.wikidata.org/entity/Q1047040'), ('currName', 'Monegasque franc')]
# [('country', 'http://www.wikidata.org/entity/Q238'), ('cName', 'San Marino'), ('previousCurrency', 'http://www.wikidata.org/entity/Q1063029'), ('currName', 'Sammarinese lira')]
# [('country', 'http://www.wikidata.org/entity/Q215'), ('cName', 'Slovenia'), ('previousCurrency', 'http://www.wikidata.org/entity/Q208133'), ('currName', 'Slovenian tolar')]
# 25

# %% [markdown]
# ## Task 5
# Return all types of dollar in the world (US Dollar, Australian Dollar, ecc...)

# %%
#return currencies whose name contains [dD]ollar
queryString = """
SELECT ?o ?name
WHERE {
   # ?s wdt:P38 ?o.
   
   # get the label
   # ?o sc:name ?name
   FILTER REGEX(?name,".*[dD]ollar.*")
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('o', 'http://www.wikidata.org/entity/Q3712659'), ('name', 'Texas Dollar')]
# [('o', 'http://www.wikidata.org/entity/Q209792'), ('name', 'Jamaican dollar')]
# [('o', 'http://www.wikidata.org/entity/Q209792'), ('name', 'Jamaican dollar')]
# [('o', 'http://www.wikidata.org/entity/Q392858'), ('name', 'Rhodesian dollar')]
# [('o', 'http://www.wikidata.org/entity/Q392858'), ('name', 'Rhodesian dollar')]
# [('o', 'http://www.wikidata.org/entity/Q1104069'), ('name', 'Canadian dollar')]
# [('o', 'http://www.wikidata.org/entity/Q1104069'), ('name', 'Canadian dollar')]
# [('o', 'http://www.wikidata.org/entity/Q1104069'), ('name', 'Canadian dollar')]
# [('o', 'http://www.wikidata.org/entity/Q1104069'), ('name', 'Canadian dollar')]
# [('o', 'http://www.wikidata.org/entity/Q1104069'), ('name', 'Canadian dollar')]
# [('o', 'http://www.wikidata.org/entity/Q1104069'), ('name', 'Canadian dollar')]
# [('o', 'http://www.wikidata.org/entity/Q1104069'), ('name', 'Canadian dollar')]
# [('o', 'http://www.wikidata.org/entity/Q1104069'), ('name', 'Canadian dollar')]
# [('o', 'http://www.wikidata.org/entity/Q1104069'), ('name', 'Canadian dollar')]
# [('o', 'http://www.wikidata.org/entity/Q1104069'), ('name', 'Canadian dollar')]
# [('o', 'http://www.wikidata.org/entity/Q1104069'), ('name', 'Canadian dollar')]
# [('o', 'http://www.wikidata.org/entity/Q1104069'), ('name', 'Canadian dollar')]
# [('o', 'http://www.wikidata.org/entity/Q1104069'), ('name', 'Canadian dollar')]
# [('o', 'http://www.wikidata.org/entity/Q1104069'), ('name', 'Canadian dollar')]
# [('o', 'http://www.wikidata.org/entity/Q1104069'), ('name', 'Canadian dollar')]
# [('o', 'http://www.wikidata.org/entity/Q1104069'), ('name', 'Canadian dollar')]
# [('o', 'http://www.wikidata.org/entity/Q1104069'), ('name', 'Canadian dollar')]
# [('o', 'http://www.wikidata.org/entity/Q259502'), ('name', 'Australian dollar')]
# [('o', 'http://www.wikidata.org/entity/Q259502'), ('name', 'Australian dollar')]
# [('o', 'http://www.wikidata.org/entity/Q259502'), ('name', 'Australian dollar')]
# [('o', 'http://www.wikidata.org/entity/Q259502'), ('name', 'Australian dollar')]
# [('o', 'http://www.wikidata.org/entity/Q259502'), ('name', 'Australian dollar')]
# [('o', 'http://www.wikidata.org/entity/Q259502'), ('name', 'Australian dollar')]
# [('o', 'http://www.wikidata.org/entity/Q259502'), ('name', 'Australian dollar')]
# [('o', 'http://www.wikidata.org/entity/Q259502'), ('name', 'Australian dollar')]
# [('o', 'http://www.wikidata.org/entity/Q259502'), ('name', 'Australian dollar')]
# [('o', 'http://www.wikidata.org/entity/Q259502'), ('name', 'Australian dollar')]
# [('o', 'http://www.wikidata.org/entity/Q259502'), ('name', 'Australian dollar')]
# [('o', 'http://www.wikidata.org/entity/Q259502'), ('name', 'Australian dollar')]
# [('o', 'http://www.wikidata.org/entity/Q259502'), ('name', 'Australian dollar')]
# [('o', 'http://www.wikidata.org/entity/Q259502'), ('name', 'Australian dollar')]
# [('o', 'http://www.wikidata.org/entity/Q259502'), ('name', 'Australian dollar')]
# [('o', 'http://www.wikidata.org/entity/Q4597'), ('name', 'Solomon Islands dollar')]
# [('o', 'http://www.wikidata.org/entity/Q4597'), ('name', 'Solomon Islands dollar')]
# [('o', 'http://www.wikidata.org/entity/Q4917'), ('name', 'United States dollar')]
# [('o', 'http://www.wikidata.org/entity/Q4917'), ('name', 'United States dollar')]
# [('o', 'http://www.wikidata.org/entity/Q4917'), ('name', 'United States dollar')]
# [('o', 'http://www.wikidata.org/entity/Q4917'), ('name', 'United States dollar')]
# [('o', 'http://www.wikidata.org/entity/Q4917'), ('name', 'United States dollar')]
# [('o', 'http://www.wikidata.org/entity/Q4917'), ('name', 'United States dollar')]
# [('o', 'http://www.wikidata.org/entity/Q4917'), ('name', 'United States dollar')]
# [('o', 'http://www.wikidata.org/entity/Q4917'), ('name', 'United States dollar')]
# [('o', 'http://www.wikidata.org/entity/Q4917'), ('name', 'United States dollar')]
# [('o', 'http://www.wikidata.org/entity/Q4917'), ('name', 'United States dollar')]
# [('o', 'http://www.wikidata.org/entity/Q4917'), ('name', 'United States dollar')]
# [('o', 'http://www.wikidata.org/entity/Q4917'), ('name', 'United States dollar')]
# [('o', 'http://www.wikidata.org/entity/Q4917'), ('name', 'United States dollar')]
# [('o', 'http://www.wikidata.org/entity/Q4917'), ('name', 'United States dollar')]
# [('o', 'http://www.wikidata.org/entity/Q4917'), ('name', 'United States dollar')]
# [('o', 'http://www.wikidata.org/entity/Q4917'), ('name', 'United States dollar')]
# [('o', 'http://www.wikidata.org/entity/Q4917'), ('name', 'United States dollar')]
# [('o', 'http://www.wikidata.org/entity/Q4917'), ('name', 'United States dollar')]
# [('o', 'http://www.wikidata.org/entity/Q4917'), ('name', 'United States dollar')]
# [('o', 'http://www.wikidata.org/entity/Q4917'), ('name', 'United States dollar')]
# [('o', 'http://www.wikidata.org/entity/Q4917'), ('name', 'United States dollar')]
# [('o', 'http://www.wikidata.org/entity/Q4917'), ('name', 'United States dollar')]
# [('o', 'http://www.wikidata.org/entity/Q4917'), ('name', 'United States dollar')]
# [('o', 'http://www.wikidata.org/entity/Q4917'), ('name', 'United States dollar')]
# [('o', 'http://www.wikidata.org/entity/Q4917'), ('name', 'United States dollar')]
# [('o', 'http://www.wikidata.org/entity/Q4917'), ('name', 'United States dollar')]
# [('o', 'http://www.wikidata.org/entity/Q4917'), ('name', 'United States dollar')]
# [('o', 'http://www.wikidata.org/entity/Q4917'), ('name', 'United States dollar')]
# [('o', 'http://www.wikidata.org/entity/Q4917'), ('name', 'United States dollar')]
# [('o', 'http://www.wikidata.org/entity/Q4917'), ('name', 'United States dollar')]
# [('o', 'http://www.wikidata.org/entity/Q4917'), ('name', 'United States dollar')]
# [('o', 'http://www.wikidata.org/entity/Q4917'), ('name', 'United States dollar')]
# [('o', 'http://www.wikidata.org/entity/Q4917'), ('name', 'United States dollar')]
# [('o', 'http://www.wikidata.org/entity/Q4917'), ('name', 'United States dollar')]
# [('o', 'http://www.wikidata.org/entity/Q4917'), ('name', 'United States dollar')]
# [('o', 'http://www.wikidata.org/entity/Q4917'), ('name', 'United States dollar')]
# [('o', 'http://www.wikidata.org/entity/Q4917'), ('name', 'United States dollar')]
# [('o', 'http://www.wikidata.org/entity/Q4917'), ('name', 'United States dollar')]
# [('o', 'http://www.wikidata.org/entity/Q4917'), ('name', 'United States dollar')]
# [('o', 'http://www.wikidata.org/entity/Q4917'), ('name', 'United States dollar')]
# [('o', 'http://www.wikidata.org/entity/Q4917'), ('name', 'United States dollar')]
# [('o', 'http://www.wikidata.org/entity/Q4917'), ('name', 'United States dollar')]
# [('o', 'http://www.wikidata.org/entity/Q4917'), ('name', 'United States dollar')]
# [('o', 'http://www.wikidata.org/entity/Q4917'), ('name', 'United States dollar')]
# [('o', 'http://www.wikidata.org/entity/Q4917'), ('name', 'United States dollar')]
# [('o', 'http://www.wikidata.org/entity/Q4917'), ('name', 'United States dollar')]
# [('o', 'http://www.wikidata.org/entity/Q4917'), ('name', 'United States dollar')]
# [('o', 'http://www.wikidata.org/entity/Q4917'), ('name', 'United States dollar')]
# [('o', 'http://www.wikidata.org/entity/Q4917'), ('name', 'United States dollar')]
# [('o', 'http://www.wikidata.org/entity/Q4917'), ('name', 'United States dollar')]
# [('o', 'http://www.wikidata.org/entity/Q4917'), ('name', 'United States dollar')]
# [('o', 'http://www.wikidata.org/entity/Q4917'), ('name', 'United States dollar')]
# [('o', 'http://www.wikidata.org/entity/Q4917'), ('name', 'United States dollar')]
# [('o', 'http://www.wikidata.org/entity/Q4917'), ('name', 'United States dollar')]
# [('o', 'http://www.wikidata.org/entity/Q4917'), ('name', 'United States dollar')]
# [('o', 'http://www.wikidata.org/entity/Q4917'), ('name', 'United States dollar')]
# [('o', 'http://www.wikidata.org/entity/Q4917'), ('name', 'United States dollar')]
# [('o', 'http://www.wikidata.org/entity/Q4917'), ('name', 'United States dollar')]
# [('o', 'http://www.wikidata.org/entity/Q4917'), ('name', 'United States dollar')]
# [('o', 'http://www.wikidata.org/entity/Q4917'), ('name', 'United States dollar')]
# [('o', 'http://www.wikidata.org/entity/Q4917'), ('name', 'United States dollar')]
# 100

# %%
# add distinct
queryString = """
SELECT DISTINCT ?o ?name
WHERE {
   # ?s wdt:P38 ?o.
   
   # get the label
   # ?o sc:name ?name
   FILTER REGEX(?name,".*[dD]ollar.*")
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('o', 'http://www.wikidata.org/entity/Q3712659'), ('name', 'Texas Dollar')]
# [('o', 'http://www.wikidata.org/entity/Q209792'), ('name', 'Jamaican dollar')]
# [('o', 'http://www.wikidata.org/entity/Q392858'), ('name', 'Rhodesian dollar')]
# [('o', 'http://www.wikidata.org/entity/Q1104069'), ('name', 'Canadian dollar')]
# [('o', 'http://www.wikidata.org/entity/Q259502'), ('name', 'Australian dollar')]
# [('o', 'http://www.wikidata.org/entity/Q4597'), ('name', 'Solomon Islands dollar')]
# [('o', 'http://www.wikidata.org/entity/Q4917'), ('name', 'United States dollar')]
# [('o', 'http://www.wikidata.org/entity/Q26365'), ('name', 'Eastern Caribbean dollar')]
# [('o', 'http://www.wikidata.org/entity/Q650834'), ('name', 'Japanese government-issued dollar in Singapore, Malaya, North Borneo, Sarawak and Brunei')]
# [('o', 'http://www.wikidata.org/entity/Q2411666'), ('name', 'Newfoundland dollar')]
# [('o', 'http://www.wikidata.org/entity/Q242988'), ('name', 'Liberian dollar')]
# [('o', 'http://www.wikidata.org/entity/Q261447'), ('name', 'Straits dollar')]
# [('o', 'http://www.wikidata.org/entity/Q4592'), ('name', 'Fijian dollar')]
# [('o', 'http://www.wikidata.org/entity/Q1472704'), ('name', 'New Zealand dollar')]
# [('o', 'http://www.wikidata.org/entity/Q2407759'), ('name', 'Malaya and British Borneo dollar')]
# [('o', 'http://www.wikidata.org/entity/Q2414453'), ('name', 'Sarawak dollar')]
# [('o', 'http://www.wikidata.org/entity/Q1323382'), ('name', 'New Brunswick dollar')]
# [('o', 'http://www.wikidata.org/entity/Q242890'), ('name', 'Trinidad and Tobago dollar')]
# [('o', 'http://www.wikidata.org/entity/Q942092'), ('name', 'British West Indies dollar')]
# [('o', 'http://www.wikidata.org/entity/Q15039722'), ('name', 'spanish dollar')]
# [('o', 'http://www.wikidata.org/entity/Q31015'), ('name', 'Hong Kong dollar')]
# [('o', 'http://www.wikidata.org/entity/Q352796'), ('name', 'trade dollar')]
# [('o', 'http://www.wikidata.org/entity/Q19831166'), ('name', 'Conch Dollar')]
# [('o', 'http://www.wikidata.org/entity/Q194351'), ('name', 'Barbadian dollar')]
# [('o', 'http://www.wikidata.org/entity/Q1049963'), ('name', 'Kiribati dollar')]
# [('o', 'http://www.wikidata.org/entity/Q275112'), ('name', 'Belize dollar')]
# [('o', 'http://www.wikidata.org/entity/Q4406'), ('name', 'Tuvaluan dollar')]
# [('o', 'http://www.wikidata.org/entity/Q1934986'), ('name', 'Nova Scotian dollar')]
# [('o', 'http://www.wikidata.org/entity/Q213005'), ('name', 'Guyanese dollar')]
# [('o', 'http://www.wikidata.org/entity/Q210478'), ('name', 'Bermudian dollar')]
# [('o', 'http://www.wikidata.org/entity/Q2344772'), ('name', 'Malayan dollar')]
# [('o', 'http://www.wikidata.org/entity/Q2328868'), ('name', 'Hawaiian dollar')]
# [('o', 'http://www.wikidata.org/entity/Q319885'), ('name', 'Cayman Islands dollar')]
# [('o', 'http://www.wikidata.org/entity/Q202036'), ('name', 'Surinamese dollar')]
# [('o', 'http://www.wikidata.org/entity/Q202462'), ('name', 'Namibian dollar')]
# [('o', 'http://www.wikidata.org/entity/Q206319'), ('name', 'Brunei dollar')]
# [('o', 'http://www.wikidata.org/entity/Q686163'), ('name', 'Confederate States dollar')]
# [('o', 'http://www.wikidata.org/entity/Q726666'), ('name', 'Mongolian dollar')]
# [('o', 'http://www.wikidata.org/entity/Q2296365'), ('name', 'British North Borneo dollar')]
# [('o', 'http://www.wikidata.org/entity/Q100966169'), ('name', 'Linden Dollar')]
# [('o', 'http://www.wikidata.org/entity/Q208526'), ('name', 'New Taiwan dollar')]
# [('o', 'http://www.wikidata.org/entity/Q16080864'), ('name', 'Province of Canada dollar')]
# [('o', 'http://www.wikidata.org/entity/Q4165057'), ('name', 'Niue dollar')]
# [('o', 'http://www.wikidata.org/entity/Q4165058'), ('name', 'Pitcairn Islands dollar')]
# [('o', 'http://www.wikidata.org/entity/Q190951'), ('name', 'Singapore dollar')]
# [('o', 'http://www.wikidata.org/entity/Q507737'), ('name', 'Cook Islands dollar')]
# [('o', 'http://www.wikidata.org/entity/Q194339'), ('name', 'Bahamian dollar')]
# [('o', 'http://www.wikidata.org/entity/Q1607372'), ('name', 'Kiautschou dollar')]
# 48

# %%
#return subject with currency Japanese government-issued dollar in Singapore, Malaya, North Borneo, Sarawak and Brunei
queryString = """
SELECT DISTINCT ?s ?name
WHERE {
   # ?s wdt:P38 wd:Q650834.
   
   # get the label
   # ?s sc:name ?name
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('s', 'http://www.wikidata.org/entity/Q715645'), ('name', 'Japanese occupation of Singapore')]
# [('s', 'http://www.wikidata.org/entity/Q713768'), ('name', 'Japanese occupation of Malaya')]
# [('s', 'http://www.wikidata.org/entity/Q15243087'), ('name', 'Japanese occupation of British Borneo')]
# 3

# %%
# remove obsolete currencies
queryString = """
SELECT DISTINCT ?o ?name
WHERE {
   # ?s wdt:P38 ?o.
   
   # get the label
   # ?o sc:name ?name.
   FILTER REGEX(?name,".*[dD]ollar.*")
   FILTER(NOT EXISTS {?o wdt:P31 wd:Q28783456})
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('o', 'http://www.wikidata.org/entity/Q3712659'), ('name', 'Texas Dollar')]
# [('o', 'http://www.wikidata.org/entity/Q209792'), ('name', 'Jamaican dollar')]
# [('o', 'http://www.wikidata.org/entity/Q1104069'), ('name', 'Canadian dollar')]
# [('o', 'http://www.wikidata.org/entity/Q259502'), ('name', 'Australian dollar')]
# [('o', 'http://www.wikidata.org/entity/Q4597'), ('name', 'Solomon Islands dollar')]
# [('o', 'http://www.wikidata.org/entity/Q4917'), ('name', 'United States dollar')]
# [('o', 'http://www.wikidata.org/entity/Q26365'), ('name', 'Eastern Caribbean dollar')]
# [('o', 'http://www.wikidata.org/entity/Q650834'), ('name', 'Japanese government-issued dollar in Singapore, Malaya, North Borneo, Sarawak and Brunei')]
# [('o', 'http://www.wikidata.org/entity/Q2411666'), ('name', 'Newfoundland dollar')]
# [('o', 'http://www.wikidata.org/entity/Q242988'), ('name', 'Liberian dollar')]
# [('o', 'http://www.wikidata.org/entity/Q261447'), ('name', 'Straits dollar')]
# [('o', 'http://www.wikidata.org/entity/Q4592'), ('name', 'Fijian dollar')]
# [('o', 'http://www.wikidata.org/entity/Q1472704'), ('name', 'New Zealand dollar')]
# [('o', 'http://www.wikidata.org/entity/Q2407759'), ('name', 'Malaya and British Borneo dollar')]
# [('o', 'http://www.wikidata.org/entity/Q2414453'), ('name', 'Sarawak dollar')]
# [('o', 'http://www.wikidata.org/entity/Q1323382'), ('name', 'New Brunswick dollar')]
# [('o', 'http://www.wikidata.org/entity/Q242890'), ('name', 'Trinidad and Tobago dollar')]
# [('o', 'http://www.wikidata.org/entity/Q942092'), ('name', 'British West Indies dollar')]
# [('o', 'http://www.wikidata.org/entity/Q15039722'), ('name', 'spanish dollar')]
# [('o', 'http://www.wikidata.org/entity/Q31015'), ('name', 'Hong Kong dollar')]
# [('o', 'http://www.wikidata.org/entity/Q352796'), ('name', 'trade dollar')]
# [('o', 'http://www.wikidata.org/entity/Q19831166'), ('name', 'Conch Dollar')]
# [('o', 'http://www.wikidata.org/entity/Q194351'), ('name', 'Barbadian dollar')]
# [('o', 'http://www.wikidata.org/entity/Q1049963'), ('name', 'Kiribati dollar')]
# [('o', 'http://www.wikidata.org/entity/Q275112'), ('name', 'Belize dollar')]
# [('o', 'http://www.wikidata.org/entity/Q4406'), ('name', 'Tuvaluan dollar')]
# [('o', 'http://www.wikidata.org/entity/Q1934986'), ('name', 'Nova Scotian dollar')]
# [('o', 'http://www.wikidata.org/entity/Q213005'), ('name', 'Guyanese dollar')]
# [('o', 'http://www.wikidata.org/entity/Q210478'), ('name', 'Bermudian dollar')]
# [('o', 'http://www.wikidata.org/entity/Q2344772'), ('name', 'Malayan dollar')]
# [('o', 'http://www.wikidata.org/entity/Q2328868'), ('name', 'Hawaiian dollar')]
# [('o', 'http://www.wikidata.org/entity/Q319885'), ('name', 'Cayman Islands dollar')]
# [('o', 'http://www.wikidata.org/entity/Q202036'), ('name', 'Surinamese dollar')]
# [('o', 'http://www.wikidata.org/entity/Q202462'), ('name', 'Namibian dollar')]
# [('o', 'http://www.wikidata.org/entity/Q206319'), ('name', 'Brunei dollar')]
# [('o', 'http://www.wikidata.org/entity/Q686163'), ('name', 'Confederate States dollar')]
# [('o', 'http://www.wikidata.org/entity/Q726666'), ('name', 'Mongolian dollar')]
# [('o', 'http://www.wikidata.org/entity/Q2296365'), ('name', 'British North Borneo dollar')]
# [('o', 'http://www.wikidata.org/entity/Q100966169'), ('name', 'Linden Dollar')]
# [('o', 'http://www.wikidata.org/entity/Q208526'), ('name', 'New Taiwan dollar')]
# [('o', 'http://www.wikidata.org/entity/Q16080864'), ('name', 'Province of Canada dollar')]
# [('o', 'http://www.wikidata.org/entity/Q4165057'), ('name', 'Niue dollar')]
# [('o', 'http://www.wikidata.org/entity/Q4165058'), ('name', 'Pitcairn Islands dollar')]
# [('o', 'http://www.wikidata.org/entity/Q190951'), ('name', 'Singapore dollar')]
# [('o', 'http://www.wikidata.org/entity/Q507737'), ('name', 'Cook Islands dollar')]
# [('o', 'http://www.wikidata.org/entity/Q194339'), ('name', 'Bahamian dollar')]
# [('o', 'http://www.wikidata.org/entity/Q1607372'), ('name', 'Kiautschou dollar')]
# 47

# %%
# try with instance of currency
queryString = """
SELECT DISTINCT ?o ?name
WHERE {
   # ?s wdt:P31 wd:Q8142.
   
   # get the label
   # ?o sc:name ?name
   FILTER REGEX(?name,".*[dD]ollar.*")
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('o', 'http://www.wikidata.org/entity/Q16194032'), ('name', 'John Dollar')]
# [('o', 'http://www.wikidata.org/entity/Q17005047'), ('name', 'Elgin, Illinois, Centennial half dollar')]
# [('o', 'http://www.wikidata.org/entity/Q17013886'), ('name', 'Million Dollar Minute')]
# [('o', 'http://www.wikidata.org/entity/Q17022048'), ('name', 'Million Dollar Arm')]
# [('o', 'http://www.wikidata.org/entity/Q17778146'), ('name', 'Dollar, Harviestoun Road, East Lodge')]
# [('o', 'http://www.wikidata.org/entity/Q17778294'), ('name', 'Dollar, 1-5 Academy Place')]
# [('o', 'http://www.wikidata.org/entity/Q17778380'), ('name', 'Dollar, 1 Devon Road')]
# [('o', 'http://www.wikidata.org/entity/Q17778450'), ('name', 'Dollar, 1 Bridge Street, Seberham')]
# [('o', 'http://www.wikidata.org/entity/Q17778578'), ('name', 'Dollar, 15 High Street')]
# [('o', 'http://www.wikidata.org/entity/Q17778678'), ('name', 'Dollar, Bridge Street, Telephone Call Box')]
# [('o', 'http://www.wikidata.org/entity/Q17778773'), ('name', 'Dollar, Kellybank House')]
# [('o', 'http://www.wikidata.org/entity/Q22249708'), ('name', 'United States five hundred-dollar bill')]
# [('o', 'http://www.wikidata.org/entity/Q21677175'), ('name', 'Extension:DollarSign')]
# [('o', 'http://www.wikidata.org/entity/Q31036443'), ('name', 'Making dollars out of DNA. The first major patent in biotechnology and the commercialization of molecular biology, 1974-1980.')]
# [('o', 'http://www.wikidata.org/entity/Q22565415'), ('name', 'Seven Million Dollar Ridge')]
# [('o', 'http://www.wikidata.org/entity/Q22641209'), ('name', 'Dollarman Bank')]
# [('o', 'http://www.wikidata.org/entity/Q22942905'), ('name', 'Dollard-Des Ormeaux')]
# [('o', 'http://www.wikidata.org/entity/Q52513856'), ('name', 'A rho-like protein is involved in the organisation of the contractile ring in dividing sand dollar eggs.')]
# [('o', 'http://www.wikidata.org/entity/Q51347299'), ('name', 'Conservation: dollars and sense.')]
# [('o', 'http://www.wikidata.org/entity/Q26252715'), ('name', 'Million Dollar Extreme Presents: World Peace')]
# [('o', 'http://www.wikidata.org/entity/Q33246878'), ('name', 'Dollar Lake')]
# [('o', 'http://www.wikidata.org/entity/Q34454372'), ('name', 'A million dollar measles outbreak: epidemiology, risk factors, and a selective revaccination strategy.')]
# [('o', 'http://www.wikidata.org/entity/Q71422355'), ('name', 'Dollar estimates of the consequences of tobacco use in Canada, 1979')]
# [('o', 'http://www.wikidata.org/entity/Q24555071'), ('name', "Getting more for their dollar: a comparison of the NHS with California's Kaiser Permanente")]
# [('o', 'http://www.wikidata.org/entity/Q34766971'), ('name', 'Stretching the managed care dollar in the new millennium: the practice of detailing primary care physicians.')]
# [('o', 'http://www.wikidata.org/entity/Q42042786'), ('name', 'Collecting the first dollars for JEAB.')]
# [('o', 'http://www.wikidata.org/entity/Q51909952'), ('name', 'Understanding the effects of low salinity on fertilization success and early development in the sand dollar Echinarachnius parma.')]
# [('o', 'http://www.wikidata.org/entity/Q34625494'), ('name', 'The burden of allergic rhinitis: beyond dollars and cents.')]
# [('o', 'http://www.wikidata.org/entity/Q42764301'), ('name', 'Direct to consumer drug advertising is billion dollar business in US.')]
# [('o', 'http://www.wikidata.org/entity/Q38952953'), ('name', 'Phylogeography of the sand dollar genus Mellita: cryptic speciation along the coasts of the Americas.')]
# [('o', 'http://www.wikidata.org/entity/Q34982276'), ('name', 'Dollars and scents: commercial opportunities in olfaction and taste.')]
# [('o', 'http://www.wikidata.org/entity/Q71493061'), ('name', 'Cost-effective care of end-stage renal disease: a billion dollar question')]
# [('o', 'http://www.wikidata.org/entity/Q550207'), ('name', 'international United States dollar')]
# [('o', 'http://www.wikidata.org/entity/Q590402'), ('name', 'La morte non conta i dollari')]
# [('o', 'http://www.wikidata.org/entity/Q201833'), ('name', 'half dollar')]
# [('o', 'http://www.wikidata.org/entity/Q2068599'), ('name', 'Million Dollar Maybe')]
# [('o', 'http://www.wikidata.org/entity/Q2542468'), ('name', 'Walking Liberty half dollar')]
# [('o', 'http://www.wikidata.org/entity/Q3373799'), ('name', 'Peace dollar')]
# [('o', 'http://www.wikidata.org/entity/Q5067981'), ('name', 'Chained dollars')]
# [('o', 'http://www.wikidata.org/entity/Q17673076'), ('name', 'United States authorities bust multimillion dollar drug ring in New Jersey')]
# [('o', 'http://www.wikidata.org/entity/Q18164029'), ('name', 'Bought for a Dollar, Sold for a Dime')]
# [('o', 'http://www.wikidata.org/entity/Q4911996'), ('name', 'Billion Dollar Gravy')]
# [('o', 'http://www.wikidata.org/entity/Q19114349'), ('name', 'Land v. Dollar')]
# [('o', 'http://www.wikidata.org/entity/Q47193632'), ('name', 'Fertilization selection on egg and jelly-coat size in the sand dollar Dendraster excentricus.')]
# [('o', 'http://www.wikidata.org/entity/Q28961286'), ('name', 'Millie Dollar')]
# [('o', 'http://www.wikidata.org/entity/Q18719376'), ('name', 'Sarah Dollard')]
# [('o', 'http://www.wikidata.org/entity/Q47920380'), ('name', 'A half-billion-dollar bid to head off emerging diseases.')]
# [('o', 'http://www.wikidata.org/entity/Q42938868'), ('name', 'A million-dollar work-up for abdominal pain: is it worth it?')]
# [('o', 'http://www.wikidata.org/entity/Q54496512'), ('name', 'Where health care dollars are spent when pediatric palliative care is provided.')]
# [('o', 'http://www.wikidata.org/entity/Q50181680'), ('name', 'Dollars may not buy as many QALYs as we think: a problem with defining quality-of-life adjustments.')]
# [('o', 'http://www.wikidata.org/entity/Q47352220'), ('name', 'Improving health with tobacco dollars from the MSA: the Arkansas experience.')]
# [('o', 'http://www.wikidata.org/entity/Q48762157'), ('name', 'The effect of monetary incentives and peer support groups on repeat adolescent pregnancies. A randomized trial of the Dollar-a-Day Program.')]
# [('o', 'http://www.wikidata.org/entity/Q64212140'), ('name', 'Actin-mediated retraction of the larval epidermis during metamorphosis of the sand dollar, Dendraster excentricus')]
# [('o', 'http://www.wikidata.org/entity/Q36415021'), ('name', 'Redistribution of fluorescently labeled tubulin in the mitotic apparatus of sand dollar eggs and the effects of taxol.')]
# [('o', 'http://www.wikidata.org/entity/Q47969942'), ('name', 'Busting the billion-dollar myth: how to slash the cost of drug development.')]
# [('o', 'http://www.wikidata.org/entity/Q52101128'), ('name', '[Influence of the activator of transcription GAL4 on growth and development of embryos and embryonic cells in primary cultures of sand dollar]')]
# [('o', 'http://www.wikidata.org/entity/Q19931195'), ('name', 'Dollar Bill')]
# [('o', 'http://www.wikidata.org/entity/Q3712659'), ('name', 'Texas Dollar')]
# [('o', 'http://www.wikidata.org/entity/Q209792'), ('name', 'Jamaican dollar')]
# [('o', 'http://www.wikidata.org/entity/Q392858'), ('name', 'Rhodesian dollar')]
# [('o', 'http://www.wikidata.org/entity/Q425836'), ('name', 'Million Dollar Password')]
# [('o', 'http://www.wikidata.org/entity/Q153677'), ('name', 'For a Few Dollars More')]
# [('o', 'http://www.wikidata.org/entity/Q7143388'), ('name', 'Pat Dollard')]
# [('o', 'http://www.wikidata.org/entity/Q2442602'), ('name', 'A Fishful of Dollars')]
# [('o', 'http://www.wikidata.org/entity/Q186744'), ('name', 'Phoebe Dollar')]
# [('o', 'http://www.wikidata.org/entity/Q5141623'), ('name', 'Coins of the Fijian dollar')]
# [('o', 'http://www.wikidata.org/entity/Q5141628'), ('name', 'Coins of the New Zealand dollar')]
# [('o', 'http://www.wikidata.org/entity/Q5289199'), ('name', 'Dollar')]
# [('o', 'http://www.wikidata.org/entity/Q5289204'), ('name', 'Dollar Bahu')]
# [('o', 'http://www.wikidata.org/entity/Q5289218'), ('name', 'Dollar Lake')]
# [('o', 'http://www.wikidata.org/entity/Q5289223'), ('name', 'Dollar Mountain')]
# [('o', 'http://www.wikidata.org/entity/Q5289227'), ('name', 'Dollar a Second')]
# [('o', 'http://www.wikidata.org/entity/Q5289238'), ('name', 'Dollar van')]
# [('o', 'http://www.wikidata.org/entity/Q5289251'), ('name', 'Dollars and Dimes')]
# [('o', 'http://www.wikidata.org/entity/Q5289261'), ('name', 'Dollarway School District')]
# [('o', 'http://www.wikidata.org/entity/Q20801811'), ('name', '5,000 Dollar Elopement')]
# [('o', 'http://www.wikidata.org/entity/Q36186955'), ('name', 'Toward the 1,000 dollars human genome.')]
# [('o', 'http://www.wikidata.org/entity/Q53227404'), ('name', 'A dollar is a dollar is a dollar--or is it?')]
# [('o', 'http://www.wikidata.org/entity/Q106949361'), ('name', 'Kenneth L. Cashdollar')]
# [('o', 'http://www.wikidata.org/entity/Q23944888'), ('name', 'Five Dollar Bill')]
# [('o', 'http://www.wikidata.org/entity/Q24705117'), ('name', 'The Million Dollar Duck')]
# [('o', 'http://www.wikidata.org/entity/Q24816037'), ('name', 'Sustainable business makes dollars and sense')]
# [('o', 'http://www.wikidata.org/entity/Q41119213'), ('name', 'When do the "dollars" make sense? Toward a conceptual framework for contingent valuation studies in health care.')]
# [('o', 'http://www.wikidata.org/entity/Q45371298'), ('name', 'Conserving large carnivores: dollars and fence.')]
# [('o', 'http://www.wikidata.org/entity/Q55054226'), ('name', 'Cell therapy industry: billion dollar global business with unlimited potential.')]
# [('o', 'http://www.wikidata.org/entity/Q45289132'), ('name', 'For every dollar spent--the cost-savings argument for prenatal care.')]
# [('o', 'http://www.wikidata.org/entity/Q57382920'), ('name', 'The Dollar Auction game: a paradox in noncooperative behavior and escalation')]
# [('o', 'http://www.wikidata.org/entity/Q50192828'), ('name', "'It still leaves me sixty dollars out of pocket': experiences of diabetes medical care among low-income earners in Perth.")]
# [('o', 'http://www.wikidata.org/entity/Q25255612'), ('name', 'Screening the United States blood supply for West Nile Virus: a question of blood, dollars, and sense')]
# [('o', 'http://www.wikidata.org/entity/Q1104069'), ('name', 'Canadian dollar')]
# [('o', 'http://www.wikidata.org/entity/Q11110'), ('name', 'Dollar sign')]
# [('o', 'http://www.wikidata.org/entity/Q14083'), ('name', 'dollar')]
# [('o', 'http://www.wikidata.org/entity/Q259502'), ('name', 'Australian dollar')]
# [('o', 'http://www.wikidata.org/entity/Q4597'), ('name', 'Solomon Islands dollar')]
# [('o', 'http://www.wikidata.org/entity/Q4917'), ('name', 'United States dollar')]
# [('o', 'http://www.wikidata.org/entity/Q26365'), ('name', 'Eastern Caribbean dollar')]
# [('o', 'http://www.wikidata.org/entity/Q650834'), ('name', 'Japanese government-issued dollar in Singapore, Malaya, North Borneo, Sarawak and Brunei')]
# [('o', 'http://www.wikidata.org/entity/Q1141857'), ('name', 'Three Dollar Bill')]
# [('o', 'http://www.wikidata.org/entity/Q1196836'), ('name', 'The Six Million Dollar Man')]
# [('o', 'http://www.wikidata.org/entity/Q2667647'), ('name', 'Twenty-Four Dollar Island')]
# 100

# %%
# return what united states dollar is instance of
queryString = """
SELECT DISTINCT ?o ?name
WHERE {
   wd:Q4917 wdt:P31 ?o.
   
   # ?o sc:name ?name
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('o', 'http://www.wikidata.org/entity/Q14083'), ('name', 'dollar')]
# [('o', 'http://www.wikidata.org/entity/Q8142'), ('name', 'currency')]
# [('o', 'http://www.wikidata.org/entity/Q756202'), ('name', 'reserve currency')]
# 3

# %%
# return all instances of dollar
queryString = """
SELECT DISTINCT ?s ?name
WHERE {
    # ?s wdt:P31* wd:Q14083.
   
   # ?s sc:name ?name
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('s', 'http://www.wikidata.org/entity/Q209792'), ('name', 'Jamaican dollar')]
# [('s', 'http://www.wikidata.org/entity/Q392858'), ('name', 'Rhodesian dollar')]
# [('s', 'http://www.wikidata.org/entity/Q1104069'), ('name', 'Canadian dollar')]
# [('s', 'http://www.wikidata.org/entity/Q14083'), ('name', 'dollar')]
# [('s', 'http://www.wikidata.org/entity/Q259502'), ('name', 'Australian dollar')]
# [('s', 'http://www.wikidata.org/entity/Q4597'), ('name', 'Solomon Islands dollar')]
# [('s', 'http://www.wikidata.org/entity/Q4917'), ('name', 'United States dollar')]
# [('s', 'http://www.wikidata.org/entity/Q26365'), ('name', 'Eastern Caribbean dollar')]
# [('s', 'http://www.wikidata.org/entity/Q4817670'), ('name', 'Coins and postage stamps of Sealand')]
# [('s', 'http://www.wikidata.org/entity/Q2411666'), ('name', 'Newfoundland dollar')]
# [('s', 'http://www.wikidata.org/entity/Q242988'), ('name', 'Liberian dollar')]
# [('s', 'http://www.wikidata.org/entity/Q4592'), ('name', 'Fijian dollar')]
# [('s', 'http://www.wikidata.org/entity/Q1472704'), ('name', 'New Zealand dollar')]
# [('s', 'http://www.wikidata.org/entity/Q1323382'), ('name', 'New Brunswick dollar')]
# [('s', 'http://www.wikidata.org/entity/Q242890'), ('name', 'Trinidad and Tobago dollar')]
# [('s', 'http://www.wikidata.org/entity/Q942092'), ('name', 'British West Indies dollar')]
# [('s', 'http://www.wikidata.org/entity/Q31015'), ('name', 'Hong Kong dollar')]
# [('s', 'http://www.wikidata.org/entity/Q19831166'), ('name', 'Conch Dollar')]
# [('s', 'http://www.wikidata.org/entity/Q194351'), ('name', 'Barbadian dollar')]
# [('s', 'http://www.wikidata.org/entity/Q1049963'), ('name', 'Kiribati dollar')]
# [('s', 'http://www.wikidata.org/entity/Q275112'), ('name', 'Belize dollar')]
# [('s', 'http://www.wikidata.org/entity/Q4406'), ('name', 'Tuvaluan dollar')]
# [('s', 'http://www.wikidata.org/entity/Q1934986'), ('name', 'Nova Scotian dollar')]
# [('s', 'http://www.wikidata.org/entity/Q213005'), ('name', 'Guyanese dollar')]
# [('s', 'http://www.wikidata.org/entity/Q210478'), ('name', 'Bermudian dollar')]
# [('s', 'http://www.wikidata.org/entity/Q182803'), ('name', 'Zimbabwean dollar')]
# [('s', 'http://www.wikidata.org/entity/Q2344772'), ('name', 'Malayan dollar')]
# [('s', 'http://www.wikidata.org/entity/Q2328868'), ('name', 'Hawaiian dollar')]
# [('s', 'http://www.wikidata.org/entity/Q319885'), ('name', 'Cayman Islands dollar')]
# [('s', 'http://www.wikidata.org/entity/Q202036'), ('name', 'Surinamese dollar')]
# [('s', 'http://www.wikidata.org/entity/Q202462'), ('name', 'Namibian dollar')]
# [('s', 'http://www.wikidata.org/entity/Q61692784'), ('name', 'United States dollar (currency unit)')]
# [('s', 'http://www.wikidata.org/entity/Q206319'), ('name', 'Brunei dollar')]
# [('s', 'http://www.wikidata.org/entity/Q686163'), ('name', 'Confederate States dollar')]
# [('s', 'http://www.wikidata.org/entity/Q718954'), ('name', 'Old Taiwan dollar')]
# [('s', 'http://www.wikidata.org/entity/Q208526'), ('name', 'New Taiwan dollar')]
# [('s', 'http://www.wikidata.org/entity/Q16080864'), ('name', 'Province of Canada dollar')]
# [('s', 'http://www.wikidata.org/entity/Q3712661'), ('name', 'Prince Edward Island dollar')]
# [('s', 'http://www.wikidata.org/entity/Q190951'), ('name', 'Singapore dollar')]
# [('s', 'http://www.wikidata.org/entity/Q507737'), ('name', 'Cook Islands dollar')]
# [('s', 'http://www.wikidata.org/entity/Q194339'), ('name', 'Bahamian dollar')]
# [('s', 'http://www.wikidata.org/entity/Q1607372'), ('name', 'Kiautschou dollar')]
# [('s', 'http://www.wikidata.org/entity/Q65067684'), ('name', 'RTGS Dollar')]
# 43

# %%
# return all instances of dollar with +
queryString = """
SELECT DISTINCT ?s ?name
WHERE {
    # ?s wdt:P31+ wd:Q14083.
   
   # ?s sc:name ?name
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('s', 'http://www.wikidata.org/entity/Q209792'), ('name', 'Jamaican dollar')]
# [('s', 'http://www.wikidata.org/entity/Q392858'), ('name', 'Rhodesian dollar')]
# [('s', 'http://www.wikidata.org/entity/Q1104069'), ('name', 'Canadian dollar')]
# [('s', 'http://www.wikidata.org/entity/Q259502'), ('name', 'Australian dollar')]
# [('s', 'http://www.wikidata.org/entity/Q4597'), ('name', 'Solomon Islands dollar')]
# [('s', 'http://www.wikidata.org/entity/Q4917'), ('name', 'United States dollar')]
# [('s', 'http://www.wikidata.org/entity/Q26365'), ('name', 'Eastern Caribbean dollar')]
# [('s', 'http://www.wikidata.org/entity/Q4817670'), ('name', 'Coins and postage stamps of Sealand')]
# [('s', 'http://www.wikidata.org/entity/Q2411666'), ('name', 'Newfoundland dollar')]
# [('s', 'http://www.wikidata.org/entity/Q242988'), ('name', 'Liberian dollar')]
# [('s', 'http://www.wikidata.org/entity/Q4592'), ('name', 'Fijian dollar')]
# [('s', 'http://www.wikidata.org/entity/Q1472704'), ('name', 'New Zealand dollar')]
# [('s', 'http://www.wikidata.org/entity/Q1323382'), ('name', 'New Brunswick dollar')]
# [('s', 'http://www.wikidata.org/entity/Q242890'), ('name', 'Trinidad and Tobago dollar')]
# [('s', 'http://www.wikidata.org/entity/Q942092'), ('name', 'British West Indies dollar')]
# [('s', 'http://www.wikidata.org/entity/Q31015'), ('name', 'Hong Kong dollar')]
# [('s', 'http://www.wikidata.org/entity/Q19831166'), ('name', 'Conch Dollar')]
# [('s', 'http://www.wikidata.org/entity/Q194351'), ('name', 'Barbadian dollar')]
# [('s', 'http://www.wikidata.org/entity/Q1049963'), ('name', 'Kiribati dollar')]
# [('s', 'http://www.wikidata.org/entity/Q275112'), ('name', 'Belize dollar')]
# [('s', 'http://www.wikidata.org/entity/Q4406'), ('name', 'Tuvaluan dollar')]
# [('s', 'http://www.wikidata.org/entity/Q1934986'), ('name', 'Nova Scotian dollar')]
# [('s', 'http://www.wikidata.org/entity/Q213005'), ('name', 'Guyanese dollar')]
# [('s', 'http://www.wikidata.org/entity/Q210478'), ('name', 'Bermudian dollar')]
# [('s', 'http://www.wikidata.org/entity/Q182803'), ('name', 'Zimbabwean dollar')]
# [('s', 'http://www.wikidata.org/entity/Q2344772'), ('name', 'Malayan dollar')]
# [('s', 'http://www.wikidata.org/entity/Q2328868'), ('name', 'Hawaiian dollar')]
# [('s', 'http://www.wikidata.org/entity/Q319885'), ('name', 'Cayman Islands dollar')]
# [('s', 'http://www.wikidata.org/entity/Q202036'), ('name', 'Surinamese dollar')]
# [('s', 'http://www.wikidata.org/entity/Q202462'), ('name', 'Namibian dollar')]
# [('s', 'http://www.wikidata.org/entity/Q61692784'), ('name', 'United States dollar (currency unit)')]
# [('s', 'http://www.wikidata.org/entity/Q206319'), ('name', 'Brunei dollar')]
# [('s', 'http://www.wikidata.org/entity/Q686163'), ('name', 'Confederate States dollar')]
# [('s', 'http://www.wikidata.org/entity/Q718954'), ('name', 'Old Taiwan dollar')]
# [('s', 'http://www.wikidata.org/entity/Q208526'), ('name', 'New Taiwan dollar')]
# [('s', 'http://www.wikidata.org/entity/Q16080864'), ('name', 'Province of Canada dollar')]
# [('s', 'http://www.wikidata.org/entity/Q3712661'), ('name', 'Prince Edward Island dollar')]
# [('s', 'http://www.wikidata.org/entity/Q190951'), ('name', 'Singapore dollar')]
# [('s', 'http://www.wikidata.org/entity/Q507737'), ('name', 'Cook Islands dollar')]
# [('s', 'http://www.wikidata.org/entity/Q194339'), ('name', 'Bahamian dollar')]
# [('s', 'http://www.wikidata.org/entity/Q1607372'), ('name', 'Kiautschou dollar')]
# [('s', 'http://www.wikidata.org/entity/Q65067684'), ('name', 'RTGS Dollar')]
# 42

# %%
# return all instances of dollar union countries with "dollar" in object linked by currency property
queryString = """
SELECT DISTINCT ?d ?name WHERE {
    {
    SELECT DISTINCT ?d ?name
    WHERE {
       # ?s wdt:P38 ?d.
       # ?d sc:name ?name
       FILTER REGEX(?name,".*[dD]ollar.*")
    }
    }
    UNION
    {
    SELECT DISTINCT ?d ?name
    WHERE {
        # ?d wdt:P31+ wd:Q14083.

        # ?d sc:name ?name
    }
    }
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('d', 'http://www.wikidata.org/entity/Q3712659'), ('name', 'Texas Dollar')]
# [('d', 'http://www.wikidata.org/entity/Q209792'), ('name', 'Jamaican dollar')]
# [('d', 'http://www.wikidata.org/entity/Q392858'), ('name', 'Rhodesian dollar')]
# [('d', 'http://www.wikidata.org/entity/Q1104069'), ('name', 'Canadian dollar')]
# [('d', 'http://www.wikidata.org/entity/Q259502'), ('name', 'Australian dollar')]
# [('d', 'http://www.wikidata.org/entity/Q4597'), ('name', 'Solomon Islands dollar')]
# [('d', 'http://www.wikidata.org/entity/Q4917'), ('name', 'United States dollar')]
# [('d', 'http://www.wikidata.org/entity/Q26365'), ('name', 'Eastern Caribbean dollar')]
# [('d', 'http://www.wikidata.org/entity/Q650834'), ('name', 'Japanese government-issued dollar in Singapore, Malaya, North Borneo, Sarawak and Brunei')]
# [('d', 'http://www.wikidata.org/entity/Q2411666'), ('name', 'Newfoundland dollar')]
# [('d', 'http://www.wikidata.org/entity/Q242988'), ('name', 'Liberian dollar')]
# [('d', 'http://www.wikidata.org/entity/Q261447'), ('name', 'Straits dollar')]
# [('d', 'http://www.wikidata.org/entity/Q4592'), ('name', 'Fijian dollar')]
# [('d', 'http://www.wikidata.org/entity/Q1472704'), ('name', 'New Zealand dollar')]
# [('d', 'http://www.wikidata.org/entity/Q2407759'), ('name', 'Malaya and British Borneo dollar')]
# [('d', 'http://www.wikidata.org/entity/Q2414453'), ('name', 'Sarawak dollar')]
# [('d', 'http://www.wikidata.org/entity/Q1323382'), ('name', 'New Brunswick dollar')]
# [('d', 'http://www.wikidata.org/entity/Q242890'), ('name', 'Trinidad and Tobago dollar')]
# [('d', 'http://www.wikidata.org/entity/Q942092'), ('name', 'British West Indies dollar')]
# [('d', 'http://www.wikidata.org/entity/Q15039722'), ('name', 'spanish dollar')]
# [('d', 'http://www.wikidata.org/entity/Q31015'), ('name', 'Hong Kong dollar')]
# [('d', 'http://www.wikidata.org/entity/Q352796'), ('name', 'trade dollar')]
# [('d', 'http://www.wikidata.org/entity/Q19831166'), ('name', 'Conch Dollar')]
# [('d', 'http://www.wikidata.org/entity/Q194351'), ('name', 'Barbadian dollar')]
# [('d', 'http://www.wikidata.org/entity/Q1049963'), ('name', 'Kiribati dollar')]
# [('d', 'http://www.wikidata.org/entity/Q275112'), ('name', 'Belize dollar')]
# [('d', 'http://www.wikidata.org/entity/Q4406'), ('name', 'Tuvaluan dollar')]
# [('d', 'http://www.wikidata.org/entity/Q1934986'), ('name', 'Nova Scotian dollar')]
# [('d', 'http://www.wikidata.org/entity/Q213005'), ('name', 'Guyanese dollar')]
# [('d', 'http://www.wikidata.org/entity/Q210478'), ('name', 'Bermudian dollar')]
# [('d', 'http://www.wikidata.org/entity/Q2344772'), ('name', 'Malayan dollar')]
# [('d', 'http://www.wikidata.org/entity/Q2328868'), ('name', 'Hawaiian dollar')]
# [('d', 'http://www.wikidata.org/entity/Q319885'), ('name', 'Cayman Islands dollar')]
# [('d', 'http://www.wikidata.org/entity/Q202036'), ('name', 'Surinamese dollar')]
# [('d', 'http://www.wikidata.org/entity/Q202462'), ('name', 'Namibian dollar')]
# [('d', 'http://www.wikidata.org/entity/Q206319'), ('name', 'Brunei dollar')]
# [('d', 'http://www.wikidata.org/entity/Q686163'), ('name', 'Confederate States dollar')]
# [('d', 'http://www.wikidata.org/entity/Q726666'), ('name', 'Mongolian dollar')]
# [('d', 'http://www.wikidata.org/entity/Q2296365'), ('name', 'British North Borneo dollar')]
# [('d', 'http://www.wikidata.org/entity/Q100966169'), ('name', 'Linden Dollar')]
# [('d', 'http://www.wikidata.org/entity/Q208526'), ('name', 'New Taiwan dollar')]
# [('d', 'http://www.wikidata.org/entity/Q16080864'), ('name', 'Province of Canada dollar')]
# [('d', 'http://www.wikidata.org/entity/Q4165057'), ('name', 'Niue dollar')]
# [('d', 'http://www.wikidata.org/entity/Q4165058'), ('name', 'Pitcairn Islands dollar')]
# [('d', 'http://www.wikidata.org/entity/Q190951'), ('name', 'Singapore dollar')]
# [('d', 'http://www.wikidata.org/entity/Q507737'), ('name', 'Cook Islands dollar')]
# [('d', 'http://www.wikidata.org/entity/Q194339'), ('name', 'Bahamian dollar')]
# [('d', 'http://www.wikidata.org/entity/Q1607372'), ('name', 'Kiautschou dollar')]
# [('d', 'http://www.wikidata.org/entity/Q4817670'), ('name', 'Coins and postage stamps of Sealand')]
# [('d', 'http://www.wikidata.org/entity/Q182803'), ('name', 'Zimbabwean dollar')]
# [('d', 'http://www.wikidata.org/entity/Q61692784'), ('name', 'United States dollar (currency unit)')]
# [('d', 'http://www.wikidata.org/entity/Q718954'), ('name', 'Old Taiwan dollar')]
# [('d', 'http://www.wikidata.org/entity/Q3712661'), ('name', 'Prince Edward Island dollar')]
# [('d', 'http://www.wikidata.org/entity/Q65067684'), ('name', 'RTGS Dollar')]
# 54

# %% [markdown]
# Final query for this task

# %%
#Return all types of dollar in the world (US Dollar, Australian Dollar, ecc...)
# write your final query
queryString = """
SELECT DISTINCT ?d ?name WHERE {
    {
    SELECT DISTINCT ?d ?name
    WHERE {
       # ?s wdt:P38 ?d.
       # ?d sc:name ?name
       FILTER REGEX(?name,".*[dD]ollar.*")
    }
    }
    UNION
    {
    SELECT DISTINCT ?d ?name
    WHERE {
        # ?d wdt:P31+ wd:Q14083.

        # ?d sc:name ?name
    }
    }
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('d', 'http://www.wikidata.org/entity/Q3712659'), ('name', 'Texas Dollar')]
# [('d', 'http://www.wikidata.org/entity/Q209792'), ('name', 'Jamaican dollar')]
# [('d', 'http://www.wikidata.org/entity/Q392858'), ('name', 'Rhodesian dollar')]
# [('d', 'http://www.wikidata.org/entity/Q1104069'), ('name', 'Canadian dollar')]
# [('d', 'http://www.wikidata.org/entity/Q259502'), ('name', 'Australian dollar')]
# [('d', 'http://www.wikidata.org/entity/Q4597'), ('name', 'Solomon Islands dollar')]
# [('d', 'http://www.wikidata.org/entity/Q4917'), ('name', 'United States dollar')]
# [('d', 'http://www.wikidata.org/entity/Q26365'), ('name', 'Eastern Caribbean dollar')]
# [('d', 'http://www.wikidata.org/entity/Q650834'), ('name', 'Japanese government-issued dollar in Singapore, Malaya, North Borneo, Sarawak and Brunei')]
# [('d', 'http://www.wikidata.org/entity/Q2411666'), ('name', 'Newfoundland dollar')]
# [('d', 'http://www.wikidata.org/entity/Q242988'), ('name', 'Liberian dollar')]
# [('d', 'http://www.wikidata.org/entity/Q261447'), ('name', 'Straits dollar')]
# [('d', 'http://www.wikidata.org/entity/Q4592'), ('name', 'Fijian dollar')]
# [('d', 'http://www.wikidata.org/entity/Q1472704'), ('name', 'New Zealand dollar')]
# [('d', 'http://www.wikidata.org/entity/Q2407759'), ('name', 'Malaya and British Borneo dollar')]
# [('d', 'http://www.wikidata.org/entity/Q2414453'), ('name', 'Sarawak dollar')]
# [('d', 'http://www.wikidata.org/entity/Q1323382'), ('name', 'New Brunswick dollar')]
# [('d', 'http://www.wikidata.org/entity/Q242890'), ('name', 'Trinidad and Tobago dollar')]
# [('d', 'http://www.wikidata.org/entity/Q942092'), ('name', 'British West Indies dollar')]
# [('d', 'http://www.wikidata.org/entity/Q15039722'), ('name', 'spanish dollar')]
# [('d', 'http://www.wikidata.org/entity/Q31015'), ('name', 'Hong Kong dollar')]
# [('d', 'http://www.wikidata.org/entity/Q352796'), ('name', 'trade dollar')]
# [('d', 'http://www.wikidata.org/entity/Q19831166'), ('name', 'Conch Dollar')]
# [('d', 'http://www.wikidata.org/entity/Q194351'), ('name', 'Barbadian dollar')]
# [('d', 'http://www.wikidata.org/entity/Q1049963'), ('name', 'Kiribati dollar')]
# [('d', 'http://www.wikidata.org/entity/Q275112'), ('name', 'Belize dollar')]
# [('d', 'http://www.wikidata.org/entity/Q4406'), ('name', 'Tuvaluan dollar')]
# [('d', 'http://www.wikidata.org/entity/Q1934986'), ('name', 'Nova Scotian dollar')]
# [('d', 'http://www.wikidata.org/entity/Q213005'), ('name', 'Guyanese dollar')]
# [('d', 'http://www.wikidata.org/entity/Q210478'), ('name', 'Bermudian dollar')]
# [('d', 'http://www.wikidata.org/entity/Q2344772'), ('name', 'Malayan dollar')]
# [('d', 'http://www.wikidata.org/entity/Q2328868'), ('name', 'Hawaiian dollar')]
# [('d', 'http://www.wikidata.org/entity/Q319885'), ('name', 'Cayman Islands dollar')]
# [('d', 'http://www.wikidata.org/entity/Q202036'), ('name', 'Surinamese dollar')]
# [('d', 'http://www.wikidata.org/entity/Q202462'), ('name', 'Namibian dollar')]
# [('d', 'http://www.wikidata.org/entity/Q206319'), ('name', 'Brunei dollar')]
# [('d', 'http://www.wikidata.org/entity/Q686163'), ('name', 'Confederate States dollar')]
# [('d', 'http://www.wikidata.org/entity/Q726666'), ('name', 'Mongolian dollar')]
# [('d', 'http://www.wikidata.org/entity/Q2296365'), ('name', 'British North Borneo dollar')]
# [('d', 'http://www.wikidata.org/entity/Q100966169'), ('name', 'Linden Dollar')]
# [('d', 'http://www.wikidata.org/entity/Q208526'), ('name', 'New Taiwan dollar')]
# [('d', 'http://www.wikidata.org/entity/Q16080864'), ('name', 'Province of Canada dollar')]
# [('d', 'http://www.wikidata.org/entity/Q4165057'), ('name', 'Niue dollar')]
# [('d', 'http://www.wikidata.org/entity/Q4165058'), ('name', 'Pitcairn Islands dollar')]
# [('d', 'http://www.wikidata.org/entity/Q190951'), ('name', 'Singapore dollar')]
# [('d', 'http://www.wikidata.org/entity/Q507737'), ('name', 'Cook Islands dollar')]
# [('d', 'http://www.wikidata.org/entity/Q194339'), ('name', 'Bahamian dollar')]
# [('d', 'http://www.wikidata.org/entity/Q1607372'), ('name', 'Kiautschou dollar')]
# [('d', 'http://www.wikidata.org/entity/Q4817670'), ('name', 'Coins and postage stamps of Sealand')]
# [('d', 'http://www.wikidata.org/entity/Q182803'), ('name', 'Zimbabwean dollar')]
# [('d', 'http://www.wikidata.org/entity/Q61692784'), ('name', 'United States dollar (currency unit)')]
# [('d', 'http://www.wikidata.org/entity/Q718954'), ('name', 'Old Taiwan dollar')]
# [('d', 'http://www.wikidata.org/entity/Q3712661'), ('name', 'Prince Edward Island dollar')]
# [('d', 'http://www.wikidata.org/entity/Q65067684'), ('name', 'RTGS Dollar')]
# 54

# %% [markdown]
# ## Task 6
# Return the currencies used in at least 2 different countries (return also the number of countries using each currency).

# %%
#first try of the final query
queryString = """
SELECT ?curr ?name (COUNT(?country) AS ?totCountries)
WHERE {
   # ?country wdt:P31 wd:Q6256;
            wdt:P38 ?curr.
   
   # get the label
   # ?curr sc:name ?name.
}
GROUP BY ?curr ?name 
HAVING (COUNT(?country) >= 2)
ORDER BY DESC (?totCountries)
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('curr', 'http://www.wikidata.org/entity/Q4916'), ('name', 'euro'), ('totCountries', '15')]
# [('curr', 'http://www.wikidata.org/entity/Q4917'), ('name', 'United States dollar'), ('totCountries', '11')]
# [('curr', 'http://www.wikidata.org/entity/Q861690'), ('name', 'West African CFA franc'), ('totCountries', '8')]
# [('curr', 'http://www.wikidata.org/entity/Q26365'), ('name', 'Eastern Caribbean dollar'), ('totCountries', '6')]
# [('curr', 'http://www.wikidata.org/entity/Q259502'), ('name', 'Australian dollar'), ('totCountries', '4')]
# [('curr', 'http://www.wikidata.org/entity/Q847739'), ('name', 'Central African CFA franc'), ('totCountries', '4')]
# [('curr', 'http://www.wikidata.org/entity/Q181907'), ('name', 'South African rand'), ('totCountries', '3')]
# [('curr', 'http://www.wikidata.org/entity/Q1472704'), ('name', 'New Zealand dollar'), ('totCountries', '3')]
# [('curr', 'http://www.wikidata.org/entity/Q25417'), ('name', 'Danish krone'), ('totCountries', '2')]
# [('curr', 'http://www.wikidata.org/entity/Q25344'), ('name', 'Swiss franc'), ('totCountries', '2')]
# [('curr', 'http://www.wikidata.org/entity/Q25224'), ('name', 'pound sterling'), ('totCountries', '2')]
# [('curr', 'http://www.wikidata.org/entity/Q188608'), ('name', 'Iranian rial'), ('totCountries', '2')]
# 12

# %%
#try with * operator
queryString = """
SELECT ?curr ?name (COUNT(?country) AS ?totCountries)
WHERE {
   # ?country wdt:P31 ?class;
            wdt:P38 ?curr.
   # ?class wdt:P279* wd:Q6256.
   
   # get the label
   # ?curr sc:name ?name.
}
GROUP BY ?curr ?name 
HAVING (COUNT(?country) >= 2)
ORDER BY DESC (?totCountries)
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('curr', 'http://www.wikidata.org/entity/Q4916'), ('name', 'euro'), ('totCountries', '102')]
# [('curr', 'http://www.wikidata.org/entity/Q4917'), ('name', 'United States dollar'), ('totCountries', '52')]
# [('curr', 'http://www.wikidata.org/entity/Q26365'), ('name', 'Eastern Caribbean dollar'), ('totCountries', '46')]
# [('curr', 'http://www.wikidata.org/entity/Q861690'), ('name', 'West African CFA franc'), ('totCountries', '38')]
# [('curr', 'http://www.wikidata.org/entity/Q259502'), ('name', 'Australian dollar'), ('totCountries', '26')]
# [('curr', 'http://www.wikidata.org/entity/Q847739'), ('name', 'Central African CFA franc'), ('totCountries', '24')]
# [('curr', 'http://www.wikidata.org/entity/Q25417'), ('name', 'Danish krone'), ('totCountries', '20')]
# [('curr', 'http://www.wikidata.org/entity/Q25224'), ('name', 'pound sterling'), ('totCountries', '20')]
# [('curr', 'http://www.wikidata.org/entity/Q199462'), ('name', 'Egyptian pound'), ('totCountries', '16')]
# [('curr', 'http://www.wikidata.org/entity/Q1472704'), ('name', 'New Zealand dollar'), ('totCountries', '16')]
# [('curr', 'http://www.wikidata.org/entity/Q181907'), ('name', 'South African rand'), ('totCountries', '14')]
# [('curr', 'http://www.wikidata.org/entity/Q172872'), ('name', 'Turkish lira'), ('totCountries', '12')]
# [('curr', 'http://www.wikidata.org/entity/Q200759'), ('name', 'kina'), ('totCountries', '10')]
# [('curr', 'http://www.wikidata.org/entity/Q199471'), ('name', 'Afghan afghani'), ('totCountries', '10')]
# [('curr', 'http://www.wikidata.org/entity/Q4597'), ('name', 'Solomon Islands dollar'), ('totCountries', '8')]
# [('curr', 'http://www.wikidata.org/entity/Q194351'), ('name', 'Barbadian dollar'), ('totCountries', '8')]
# [('curr', 'http://www.wikidata.org/entity/Q201799'), ('name', 'ngultrum'), ('totCountries', '8')]
# [('curr', 'http://www.wikidata.org/entity/Q201880'), ('name', 'Lebanese pound'), ('totCountries', '8')]
# [('curr', 'http://www.wikidata.org/entity/Q26360'), ('name', 'Croatian kuna'), ('totCountries', '8')]
# [('curr', 'http://www.wikidata.org/entity/Q1370372'), ('name', 'Spanish real'), ('totCountries', '8')]
# [('curr', 'http://www.wikidata.org/entity/Q240468'), ('name', 'Syrian pound'), ('totCountries', '8')]
# [('curr', 'http://www.wikidata.org/entity/Q200192'), ('name', 'Moroccan dirham'), ('totCountries', '8')]
# [('curr', 'http://www.wikidata.org/entity/Q8146'), ('name', 'Japanese yen'), ('totCountries', '8')]
# [('curr', 'http://www.wikidata.org/entity/Q15039722'), ('name', 'spanish dollar'), ('totCountries', '8')]
# [('curr', 'http://www.wikidata.org/entity/Q199674'), ('name', 'Algerian dinar'), ('totCountries', '8')]
# [('curr', 'http://www.wikidata.org/entity/Q4592'), ('name', 'Fijian dollar'), ('totCountries', '8')]
# [('curr', 'http://www.wikidata.org/entity/Q173751'), ('name', 'Kazakhstani tenge'), ('totCountries', '8')]
# [('curr', 'http://www.wikidata.org/entity/Q131309'), ('name', 'new shekel'), ('totCountries', '8')]
# [('curr', 'http://www.wikidata.org/entity/Q206243'), ('name', 'birr'), ('totCountries', '8')]
# [('curr', 'http://www.wikidata.org/entity/Q209792'), ('name', 'Jamaican dollar'), ('totCountries', '8')]
# [('curr', 'http://www.wikidata.org/entity/Q190699'), ('name', 'Libyan dinar'), ('totCountries', '8')]
# [('curr', 'http://www.wikidata.org/entity/Q25344'), ('name', 'Swiss franc'), ('totCountries', '8')]
# [('curr', 'http://www.wikidata.org/entity/Q191068'), ('name', 'Faroese króna'), ('totCountries', '8')]
# [('curr', 'http://www.wikidata.org/entity/Q17093752'), ('name', 'escudo'), ('totCountries', '8')]
# [('curr', 'http://www.wikidata.org/entity/Q4406'), ('name', 'Tuvaluan dollar'), ('totCountries', '8')]
# [('curr', 'http://www.wikidata.org/entity/Q194339'), ('name', 'Bahamian dollar'), ('totCountries', '8')]
# [('curr', 'http://www.wikidata.org/entity/Q189097'), ('name', 'peseta'), ('totCountries', '8')]
# [('curr', 'http://www.wikidata.org/entity/Q41588'), ('name', 'rupiah'), ('totCountries', '8')]
# [('curr', 'http://www.wikidata.org/entity/Q4602'), ('name', 'Tunisian dinar'), ('totCountries', '8')]
# [('curr', 'http://www.wikidata.org/entity/Q190951'), ('name', 'Singapore dollar'), ('totCountries', '6')]
# [('curr', 'http://www.wikidata.org/entity/Q207514'), ('name', 'Paraguayan guaraní'), ('totCountries', '6')]
# [('curr', 'http://www.wikidata.org/entity/Q200055'), ('name', 'Lao kip'), ('totCountries', '6')]
# [('curr', 'http://www.wikidata.org/entity/Q4588'), ('name', 'Samoan tālā'), ('totCountries', '6')]
# [('curr', 'http://www.wikidata.org/entity/Q17193'), ('name', 'Philippine peso'), ('totCountries', '6')]
# [('curr', 'http://www.wikidata.org/entity/Q201871'), ('name', 'Bahraini dinar'), ('totCountries', '6')]
# [('curr', 'http://www.wikidata.org/entity/Q4598'), ('name', 'Ugandan shilling'), ('totCountries', '6')]
# [('curr', 'http://www.wikidata.org/entity/Q238007'), ('name', 'Burundian franc'), ('totCountries', '6')]
# [('curr', 'http://www.wikidata.org/entity/Q4741'), ('name', 'Rwandan franc'), ('totCountries', '6')]
# [('curr', 'http://www.wikidata.org/entity/Q244366'), ('name', 'South Sudanese pound'), ('totCountries', '6')]
# [('curr', 'http://www.wikidata.org/entity/Q199886'), ('name', 'Tajikistani somoni'), ('totCountries', '6')]
# [('curr', 'http://www.wikidata.org/entity/Q212967'), ('name', 'Mauritian rupee'), ('totCountries', '6')]
# [('curr', 'http://www.wikidata.org/entity/Q208039'), ('name', 'Lesotho loti'), ('totCountries', '6')]
# [('curr', 'http://www.wikidata.org/entity/Q4584'), ('name', 'ariary'), ('totCountries', '6')]
# [('curr', 'http://www.wikidata.org/entity/Q206600'), ('name', 'Maldivian rufiyaa'), ('totCountries', '6')]
# [('curr', 'http://www.wikidata.org/entity/Q4596'), ('name', 'Sri Lankan rupee'), ('totCountries', '6')]
# [('curr', 'http://www.wikidata.org/entity/Q47190'), ('name', 'forint'), ('totCountries', '6')]
# [('curr', 'http://www.wikidata.org/entity/Q96051466'), ('name', 'SOV'), ('totCountries', '6')]
# [('curr', 'http://www.wikidata.org/entity/Q267264'), ('name', 'Comorian franc'), ('totCountries', '6')]
# [('curr', 'http://www.wikidata.org/entity/Q193712'), ('name', 'São Tomé and Príncipe dobra'), ('totCountries', '6')]
# [('curr', 'http://www.wikidata.org/entity/Q35881'), ('name', 'Kyrgyzstani som'), ('totCountries', '6')]
# [('curr', 'http://www.wikidata.org/entity/Q131016'), ('name', 'Czech koruna'), ('totCountries', '6')]
# [('curr', 'http://www.wikidata.org/entity/Q1049963'), ('name', 'Kiribati dollar'), ('totCountries', '6')]
# [('curr', 'http://www.wikidata.org/entity/Q242890'), ('name', 'Trinidad and Tobago dollar'), ('totCountries', '6')]
# [('curr', 'http://www.wikidata.org/entity/Q487888'), ('name', 'Uzbekistani som'), ('totCountries', '6')]
# [('curr', 'http://www.wikidata.org/entity/Q203955'), ('name', 'Gourde'), ('totCountries', '6')]
# [('curr', 'http://www.wikidata.org/entity/Q572213'), ('name', 'East Timor centavo coins'), ('totCountries', '6')]
# [('curr', 'http://www.wikidata.org/entity/Q208526'), ('name', 'New Taiwan dollar'), ('totCountries', '6')]
# [('curr', 'http://www.wikidata.org/entity/Q207523'), ('name', 'Vanuatu vatus'), ('totCountries', '6')]
# [('curr', 'http://www.wikidata.org/entity/Q106720'), ('name', 'North Korean won'), ('totCountries', '6')]
# [('curr', 'http://www.wikidata.org/entity/Q211694'), ('name', 'Malawian kwacha'), ('totCountries', '6')]
# [('curr', 'http://www.wikidata.org/entity/Q202895'), ('name', 'Nepalese rupee'), ('totCountries', '6')]
# [('curr', 'http://www.wikidata.org/entity/Q200737'), ('name', 'boliviano'), ('totCountries', '6')]
# [('curr', 'http://www.wikidata.org/entity/Q486637'), ('name', 'Turkmenistan manat'), ('totCountries', '6')]
# [('curr', 'http://www.wikidata.org/entity/Q242922'), ('name', 'Dominican peso'), ('totCountries', '6')]
# [('curr', 'http://www.wikidata.org/entity/Q4591'), ('name', 'Cape Verdean escudo'), ('totCountries', '6')]
# [('curr', 'http://www.wikidata.org/entity/Q188608'), ('name', 'Iranian rial'), ('totCountries', '6')]
# [('curr', 'http://www.wikidata.org/entity/Q183435'), ('name', 'tugrik'), ('totCountries', '6')]
# [('curr', 'http://www.wikidata.org/entity/Q4595'), ('name', 'Seychellois rupee'), ('totCountries', '6')]
# [('curr', 'http://www.wikidata.org/entity/Q21531507'), ('name', 'Belarusian ruble'), ('totCountries', '6')]
# [('curr', 'http://www.wikidata.org/entity/Q186794'), ('name', 'Botswana pula'), ('totCountries', '6')]
# [('curr', 'http://www.wikidata.org/entity/Q73408'), ('name', 'Zambian kwacha'), ('totCountries', '6')]
# [('curr', 'http://www.wikidata.org/entity/Q130498'), ('name', 'Armenian dram'), ('totCountries', '4')]
# [('curr', 'http://www.wikidata.org/entity/Q122922'), ('name', 'Swedish krona'), ('totCountries', '4')]
# [('curr', 'http://www.wikidata.org/entity/Q242915'), ('name', 'Costa Rican colón'), ('totCountries', '4')]
# [('curr', 'http://www.wikidata.org/entity/Q173117'), ('name', 'Brazilian real'), ('totCountries', '4')]
# [('curr', 'http://www.wikidata.org/entity/Q201875'), ('name', 'kyat'), ('totCountries', '4')]
# [('curr', 'http://www.wikidata.org/entity/Q193094'), ('name', 'Iraqi dinar'), ('totCountries', '4')]
# [('curr', 'http://www.wikidata.org/entity/Q183530'), ('name', 'Ghana cedi'), ('totCountries', '4')]
# [('curr', 'http://www.wikidata.org/entity/Q203722'), ('name', 'Jordanian dinar'), ('totCountries', '4')]
# [('curr', 'http://www.wikidata.org/entity/Q200050'), ('name', 'Chilean peso'), ('totCountries', '4')]
# [('curr', 'http://www.wikidata.org/entity/Q206386'), ('name', 'Qatari riyal'), ('totCountries', '4')]
# [('curr', 'http://www.wikidata.org/entity/Q200294'), ('name', 'United Arab Emirates dirham'), ('totCountries', '4')]
# [('curr', 'http://www.wikidata.org/entity/Q184172'), ('name', 'French franc'), ('totCountries', '4')]
# [('curr', 'http://www.wikidata.org/entity/Q203567'), ('name', 'Nigerian naira'), ('totCountries', '4')]
# [('curr', 'http://www.wikidata.org/entity/Q202462'), ('name', 'Namibian dollar'), ('totCountries', '4')]
# [('curr', 'http://www.wikidata.org/entity/Q4823'), ('name', 'lilangeni'), ('totCountries', '4')]
# [('curr', 'http://www.wikidata.org/entity/Q207396'), ('name', 'quetzal'), ('totCountries', '4')]
# [('curr', 'http://www.wikidata.org/entity/Q213311'), ('name', 'Guinean franc'), ('totCountries', '4')]
# [('curr', 'http://www.wikidata.org/entity/Q131645'), ('name', 'Romanian leu'), ('totCountries', '4')]
# [('curr', 'http://www.wikidata.org/entity/Q4719'), ('name', 'Honduran lempira'), ('totCountries', '4')]
# 100

# %%
#see countries for euro
queryString = """
SELECT ?country ?name 
WHERE {
   # ?country wdt:P31 ?class;
            wdt:P38 wd:Q4916.
   # ?class wdt:P279* wd:Q6256.
   
   # get the label
   # ?country sc:name ?name.
}
GROUP BY ?country ?name 
HAVING (COUNT(?country) >= 2)
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('country', 'http://www.wikidata.org/entity/Q38'), ('name', 'Italy')]
# [('country', 'http://www.wikidata.org/entity/Q183'), ('name', 'Germany')]
# [('country', 'http://www.wikidata.org/entity/Q233'), ('name', 'Malta')]
# [('country', 'http://www.wikidata.org/entity/Q41'), ('name', 'Greece')]
# [('country', 'http://www.wikidata.org/entity/Q236'), ('name', 'Montenegro')]
# [('country', 'http://www.wikidata.org/entity/Q142'), ('name', 'France')]
# [('country', 'http://www.wikidata.org/entity/Q33'), ('name', 'Finland')]
# [('country', 'http://www.wikidata.org/entity/Q40'), ('name', 'Austria')]
# [('country', 'http://www.wikidata.org/entity/Q229'), ('name', 'Cyprus')]
# [('country', 'http://www.wikidata.org/entity/Q29999'), ('name', 'Kingdom of the Netherlands')]
# [('country', 'http://www.wikidata.org/entity/Q45'), ('name', 'Portugal')]
# [('country', 'http://www.wikidata.org/entity/Q214'), ('name', 'Slovakia')]
# [('country', 'http://www.wikidata.org/entity/Q27'), ('name', 'Ireland')]
# [('country', 'http://www.wikidata.org/entity/Q211'), ('name', 'Latvia')]
# [('country', 'http://www.wikidata.org/entity/Q228'), ('name', 'Andorra')]
# 15

# %%
#see countries for euro (without having clause)
queryString = """
SELECT ?country ?name 
WHERE {
   # ?country wdt:P31 ?class;
            wdt:P38 wd:Q4916.
   # ?class wdt:P279* wd:Q6256.
   
   # get the label
   # ?country sc:name ?name.
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('country', 'http://www.wikidata.org/entity/Q142'), ('name', 'France')]
# [('country', 'http://www.wikidata.org/entity/Q142'), ('name', 'France')]
# [('country', 'http://www.wikidata.org/entity/Q142'), ('name', 'France')]
# [('country', 'http://www.wikidata.org/entity/Q142'), ('name', 'France')]
# [('country', 'http://www.wikidata.org/entity/Q183'), ('name', 'Germany')]
# [('country', 'http://www.wikidata.org/entity/Q183'), ('name', 'Germany')]
# [('country', 'http://www.wikidata.org/entity/Q191'), ('name', 'Estonia')]
# [('country', 'http://www.wikidata.org/entity/Q211'), ('name', 'Latvia')]
# [('country', 'http://www.wikidata.org/entity/Q211'), ('name', 'Latvia')]
# [('country', 'http://www.wikidata.org/entity/Q211'), ('name', 'Latvia')]
# [('country', 'http://www.wikidata.org/entity/Q214'), ('name', 'Slovakia')]
# [('country', 'http://www.wikidata.org/entity/Q214'), ('name', 'Slovakia')]
# [('country', 'http://www.wikidata.org/entity/Q214'), ('name', 'Slovakia')]
# [('country', 'http://www.wikidata.org/entity/Q215'), ('name', 'Slovenia')]
# [('country', 'http://www.wikidata.org/entity/Q228'), ('name', 'Andorra')]
# [('country', 'http://www.wikidata.org/entity/Q228'), ('name', 'Andorra')]
# [('country', 'http://www.wikidata.org/entity/Q229'), ('name', 'Cyprus')]
# [('country', 'http://www.wikidata.org/entity/Q229'), ('name', 'Cyprus')]
# [('country', 'http://www.wikidata.org/entity/Q233'), ('name', 'Malta')]
# [('country', 'http://www.wikidata.org/entity/Q233'), ('name', 'Malta')]
# [('country', 'http://www.wikidata.org/entity/Q235'), ('name', 'Monaco')]
# [('country', 'http://www.wikidata.org/entity/Q236'), ('name', 'Montenegro')]
# [('country', 'http://www.wikidata.org/entity/Q236'), ('name', 'Montenegro')]
# [('country', 'http://www.wikidata.org/entity/Q236'), ('name', 'Montenegro')]
# [('country', 'http://www.wikidata.org/entity/Q236'), ('name', 'Montenegro')]
# [('country', 'http://www.wikidata.org/entity/Q237'), ('name', 'Vatican City')]
# [('country', 'http://www.wikidata.org/entity/Q238'), ('name', 'San Marino')]
# [('country', 'http://www.wikidata.org/entity/Q27'), ('name', 'Ireland')]
# [('country', 'http://www.wikidata.org/entity/Q27'), ('name', 'Ireland')]
# [('country', 'http://www.wikidata.org/entity/Q27'), ('name', 'Ireland')]
# [('country', 'http://www.wikidata.org/entity/Q29'), ('name', 'Spain')]
# [('country', 'http://www.wikidata.org/entity/Q29999'), ('name', 'Kingdom of the Netherlands')]
# [('country', 'http://www.wikidata.org/entity/Q29999'), ('name', 'Kingdom of the Netherlands')]
# [('country', 'http://www.wikidata.org/entity/Q29999'), ('name', 'Kingdom of the Netherlands')]
# [('country', 'http://www.wikidata.org/entity/Q31'), ('name', 'Belgium')]
# [('country', 'http://www.wikidata.org/entity/Q32'), ('name', 'Luxembourg')]
# [('country', 'http://www.wikidata.org/entity/Q33'), ('name', 'Finland')]
# [('country', 'http://www.wikidata.org/entity/Q33'), ('name', 'Finland')]
# [('country', 'http://www.wikidata.org/entity/Q33'), ('name', 'Finland')]
# [('country', 'http://www.wikidata.org/entity/Q37'), ('name', 'Lithuania')]
# [('country', 'http://www.wikidata.org/entity/Q38'), ('name', 'Italy')]
# [('country', 'http://www.wikidata.org/entity/Q38'), ('name', 'Italy')]
# [('country', 'http://www.wikidata.org/entity/Q40'), ('name', 'Austria')]
# [('country', 'http://www.wikidata.org/entity/Q40'), ('name', 'Austria')]
# [('country', 'http://www.wikidata.org/entity/Q40'), ('name', 'Austria')]
# [('country', 'http://www.wikidata.org/entity/Q41'), ('name', 'Greece')]
# [('country', 'http://www.wikidata.org/entity/Q41'), ('name', 'Greece')]
# [('country', 'http://www.wikidata.org/entity/Q45'), ('name', 'Portugal')]
# [('country', 'http://www.wikidata.org/entity/Q45'), ('name', 'Portugal')]
# [('country', 'http://www.wikidata.org/entity/Q45'), ('name', 'Portugal')]
# [('country', 'http://www.wikidata.org/entity/Q55'), ('name', 'Netherlands')]
# 51

# %%
#ADD DISTINCT
queryString = """
SELECT DISTINCT ?country ?name 
WHERE {
   # ?country wdt:P31 ?class;
            wdt:P38 wd:Q4916.
   # ?class wdt:P279* wd:Q6256.
   
   # get the label
   # ?country sc:name ?name.
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('country', 'http://www.wikidata.org/entity/Q142'), ('name', 'France')]
# [('country', 'http://www.wikidata.org/entity/Q183'), ('name', 'Germany')]
# [('country', 'http://www.wikidata.org/entity/Q191'), ('name', 'Estonia')]
# [('country', 'http://www.wikidata.org/entity/Q211'), ('name', 'Latvia')]
# [('country', 'http://www.wikidata.org/entity/Q214'), ('name', 'Slovakia')]
# [('country', 'http://www.wikidata.org/entity/Q215'), ('name', 'Slovenia')]
# [('country', 'http://www.wikidata.org/entity/Q228'), ('name', 'Andorra')]
# [('country', 'http://www.wikidata.org/entity/Q229'), ('name', 'Cyprus')]
# [('country', 'http://www.wikidata.org/entity/Q233'), ('name', 'Malta')]
# [('country', 'http://www.wikidata.org/entity/Q235'), ('name', 'Monaco')]
# [('country', 'http://www.wikidata.org/entity/Q236'), ('name', 'Montenegro')]
# [('country', 'http://www.wikidata.org/entity/Q237'), ('name', 'Vatican City')]
# [('country', 'http://www.wikidata.org/entity/Q238'), ('name', 'San Marino')]
# [('country', 'http://www.wikidata.org/entity/Q27'), ('name', 'Ireland')]
# [('country', 'http://www.wikidata.org/entity/Q29'), ('name', 'Spain')]
# [('country', 'http://www.wikidata.org/entity/Q29999'), ('name', 'Kingdom of the Netherlands')]
# [('country', 'http://www.wikidata.org/entity/Q31'), ('name', 'Belgium')]
# [('country', 'http://www.wikidata.org/entity/Q32'), ('name', 'Luxembourg')]
# [('country', 'http://www.wikidata.org/entity/Q33'), ('name', 'Finland')]
# [('country', 'http://www.wikidata.org/entity/Q37'), ('name', 'Lithuania')]
# [('country', 'http://www.wikidata.org/entity/Q38'), ('name', 'Italy')]
# [('country', 'http://www.wikidata.org/entity/Q40'), ('name', 'Austria')]
# [('country', 'http://www.wikidata.org/entity/Q41'), ('name', 'Greece')]
# [('country', 'http://www.wikidata.org/entity/Q45'), ('name', 'Portugal')]
# [('country', 'http://www.wikidata.org/entity/Q55'), ('name', 'Netherlands')]
# 25

# %%
#ADD COUNT
queryString = """
SELECT DISTINCT ?country ?name (COUNT(?country) AS ?total)
WHERE {
   # ?country wdt:P31 ?class;
            wdt:P38 wd:Q4916.
   # ?class wdt:P279* wd:Q6256.
   
   # get the label
   # ?country sc:name ?name.
}
GROUP BY ?country ?name
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('country', 'http://www.wikidata.org/entity/Q215'), ('name', 'Slovenia'), ('total', '1')]
# [('country', 'http://www.wikidata.org/entity/Q235'), ('name', 'Monaco'), ('total', '1')]
# [('country', 'http://www.wikidata.org/entity/Q38'), ('name', 'Italy'), ('total', '2')]
# [('country', 'http://www.wikidata.org/entity/Q183'), ('name', 'Germany'), ('total', '2')]
# [('country', 'http://www.wikidata.org/entity/Q233'), ('name', 'Malta'), ('total', '2')]
# [('country', 'http://www.wikidata.org/entity/Q238'), ('name', 'San Marino'), ('total', '1')]
# [('country', 'http://www.wikidata.org/entity/Q37'), ('name', 'Lithuania'), ('total', '1')]
# [('country', 'http://www.wikidata.org/entity/Q41'), ('name', 'Greece'), ('total', '2')]
# [('country', 'http://www.wikidata.org/entity/Q31'), ('name', 'Belgium'), ('total', '1')]
# [('country', 'http://www.wikidata.org/entity/Q236'), ('name', 'Montenegro'), ('total', '4')]
# [('country', 'http://www.wikidata.org/entity/Q29'), ('name', 'Spain'), ('total', '1')]
# [('country', 'http://www.wikidata.org/entity/Q142'), ('name', 'France'), ('total', '4')]
# [('country', 'http://www.wikidata.org/entity/Q32'), ('name', 'Luxembourg'), ('total', '1')]
# [('country', 'http://www.wikidata.org/entity/Q33'), ('name', 'Finland'), ('total', '3')]
# [('country', 'http://www.wikidata.org/entity/Q40'), ('name', 'Austria'), ('total', '3')]
# [('country', 'http://www.wikidata.org/entity/Q229'), ('name', 'Cyprus'), ('total', '2')]
# [('country', 'http://www.wikidata.org/entity/Q237'), ('name', 'Vatican City'), ('total', '1')]
# [('country', 'http://www.wikidata.org/entity/Q29999'), ('name', 'Kingdom of the Netherlands'), ('total', '3')]
# [('country', 'http://www.wikidata.org/entity/Q45'), ('name', 'Portugal'), ('total', '3')]
# [('country', 'http://www.wikidata.org/entity/Q214'), ('name', 'Slovakia'), ('total', '3')]
# [('country', 'http://www.wikidata.org/entity/Q27'), ('name', 'Ireland'), ('total', '3')]
# [('country', 'http://www.wikidata.org/entity/Q55'), ('name', 'Netherlands'), ('total', '1')]
# [('country', 'http://www.wikidata.org/entity/Q191'), ('name', 'Estonia'), ('total', '1')]
# [('country', 'http://www.wikidata.org/entity/Q211'), ('name', 'Latvia'), ('total', '3')]
# [('country', 'http://www.wikidata.org/entity/Q228'), ('name', 'Andorra'), ('total', '2')]
# 25

# %%
#Add outer query to count correctly 
queryString = """
SELECT ?currency ?currencyName (COUNT(?country) AS ?totalCountries) WHERE {
    {    
    SELECT DISTINCT ?country ?currency ?currencyName
    WHERE {
       # ?country wdt:P31 ?class;
                wdt:P38 ?currency.
       # ?class wdt:P279* wd:Q6256.

       # get the label
       # ?currency sc:name ?currencyName.
    }
}
}
GROUP BY ?currency ?currencyName
HAVING (COUNT(?country) >= 2)
ORDER BY DESC (?totalCountries)
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('currency', 'http://www.wikidata.org/entity/Q4916'), ('currencyName', 'euro'), ('totalCountries', '25')]
# [('currency', 'http://www.wikidata.org/entity/Q4917'), ('currencyName', 'United States dollar'), ('totalCountries', '12')]
# [('currency', 'http://www.wikidata.org/entity/Q861690'), ('currencyName', 'West African CFA franc'), ('totalCountries', '8')]
# [('currency', 'http://www.wikidata.org/entity/Q26365'), ('currencyName', 'Eastern Caribbean dollar'), ('totalCountries', '6')]
# [('currency', 'http://www.wikidata.org/entity/Q847739'), ('currencyName', 'Central African CFA franc'), ('totalCountries', '6')]
# [('currency', 'http://www.wikidata.org/entity/Q259502'), ('currencyName', 'Australian dollar'), ('totalCountries', '4')]
# [('currency', 'http://www.wikidata.org/entity/Q199462'), ('currencyName', 'Egyptian pound'), ('totalCountries', '4')]
# [('currency', 'http://www.wikidata.org/entity/Q199471'), ('currencyName', 'Afghan afghani'), ('totalCountries', '3')]
# [('currency', 'http://www.wikidata.org/entity/Q181907'), ('currencyName', 'South African rand'), ('totalCountries', '3')]
# [('currency', 'http://www.wikidata.org/entity/Q25417'), ('currencyName', 'Danish krone'), ('totalCountries', '3')]
# [('currency', 'http://www.wikidata.org/entity/Q1472704'), ('currencyName', 'New Zealand dollar'), ('totalCountries', '3')]
# [('currency', 'http://www.wikidata.org/entity/Q25224'), ('currencyName', 'pound sterling'), ('totalCountries', '3')]
# [('currency', 'http://www.wikidata.org/entity/Q130498'), ('currencyName', 'Armenian dram'), ('totalCountries', '2')]
# [('currency', 'http://www.wikidata.org/entity/Q184172'), ('currencyName', 'French franc'), ('totalCountries', '2')]
# [('currency', 'http://www.wikidata.org/entity/Q8146'), ('currencyName', 'Japanese yen'), ('totalCountries', '2')]
# [('currency', 'http://www.wikidata.org/entity/Q952064'), ('currencyName', 'Roman currency'), ('totalCountries', '2')]
# [('currency', 'http://www.wikidata.org/entity/Q172872'), ('currencyName', 'Turkish lira'), ('totalCountries', '2')]
# [('currency', 'http://www.wikidata.org/entity/Q206243'), ('currencyName', 'birr'), ('totalCountries', '2')]
# [('currency', 'http://www.wikidata.org/entity/Q191830'), ('currencyName', 'dinar'), ('totalCountries', '2')]
# [('currency', 'http://www.wikidata.org/entity/Q25344'), ('currencyName', 'Swiss franc'), ('totalCountries', '2')]
# [('currency', 'http://www.wikidata.org/entity/Q188608'), ('currencyName', 'Iranian rial'), ('totalCountries', '2')]
# [('currency', 'http://www.wikidata.org/entity/Q191068'), ('currencyName', 'Faroese króna'), ('totalCountries', '2')]
# [('currency', 'http://www.wikidata.org/entity/Q41044'), ('currencyName', 'Russian ruble'), ('totalCountries', '2')]
# 23

# %%
#Add distinct on count and not outer query
queryString = """    
SELECT ?currency ?currencyName (COUNT(DISTINCT ?country) AS ?totalCountries)
    WHERE {
       # ?country wdt:P31 ?class;
                wdt:P38 ?currency.
       # ?class wdt:P279* wd:Q6256.

       # get the label
       # ?currency sc:name ?currencyName.
    }

GROUP BY ?currency ?currencyName
HAVING ( COUNT(DISTINCT ?country) >= 2)
ORDER BY DESC (?totalCountries)
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('currency', 'http://www.wikidata.org/entity/Q4916'), ('currencyName', 'euro'), ('totalCountries', '25')]
# [('currency', 'http://www.wikidata.org/entity/Q4917'), ('currencyName', 'United States dollar'), ('totalCountries', '12')]
# [('currency', 'http://www.wikidata.org/entity/Q861690'), ('currencyName', 'West African CFA franc'), ('totalCountries', '8')]
# [('currency', 'http://www.wikidata.org/entity/Q26365'), ('currencyName', 'Eastern Caribbean dollar'), ('totalCountries', '6')]
# [('currency', 'http://www.wikidata.org/entity/Q847739'), ('currencyName', 'Central African CFA franc'), ('totalCountries', '6')]
# [('currency', 'http://www.wikidata.org/entity/Q259502'), ('currencyName', 'Australian dollar'), ('totalCountries', '4')]
# [('currency', 'http://www.wikidata.org/entity/Q199462'), ('currencyName', 'Egyptian pound'), ('totalCountries', '4')]
# [('currency', 'http://www.wikidata.org/entity/Q181907'), ('currencyName', 'South African rand'), ('totalCountries', '3')]
# [('currency', 'http://www.wikidata.org/entity/Q1472704'), ('currencyName', 'New Zealand dollar'), ('totalCountries', '3')]
# [('currency', 'http://www.wikidata.org/entity/Q25224'), ('currencyName', 'pound sterling'), ('totalCountries', '3')]
# [('currency', 'http://www.wikidata.org/entity/Q25417'), ('currencyName', 'Danish krone'), ('totalCountries', '3')]
# [('currency', 'http://www.wikidata.org/entity/Q199471'), ('currencyName', 'Afghan afghani'), ('totalCountries', '3')]
# [('currency', 'http://www.wikidata.org/entity/Q130498'), ('currencyName', 'Armenian dram'), ('totalCountries', '2')]
# [('currency', 'http://www.wikidata.org/entity/Q206243'), ('currencyName', 'birr'), ('totalCountries', '2')]
# [('currency', 'http://www.wikidata.org/entity/Q952064'), ('currencyName', 'Roman currency'), ('totalCountries', '2')]
# [('currency', 'http://www.wikidata.org/entity/Q184172'), ('currencyName', 'French franc'), ('totalCountries', '2')]
# [('currency', 'http://www.wikidata.org/entity/Q25344'), ('currencyName', 'Swiss franc'), ('totalCountries', '2')]
# [('currency', 'http://www.wikidata.org/entity/Q191068'), ('currencyName', 'Faroese króna'), ('totalCountries', '2')]
# [('currency', 'http://www.wikidata.org/entity/Q172872'), ('currencyName', 'Turkish lira'), ('totalCountries', '2')]
# [('currency', 'http://www.wikidata.org/entity/Q8146'), ('currencyName', 'Japanese yen'), ('totalCountries', '2')]
# [('currency', 'http://www.wikidata.org/entity/Q41044'), ('currencyName', 'Russian ruble'), ('totalCountries', '2')]
# [('currency', 'http://www.wikidata.org/entity/Q191830'), ('currencyName', 'dinar'), ('totalCountries', '2')]
# [('currency', 'http://www.wikidata.org/entity/Q188608'), ('currencyName', 'Iranian rial'), ('totalCountries', '2')]
# 23

# %%
 #Add distinct group concat to see list of countries
queryString = """    
    SELECT ?currency ?currencyName (COUNT(DISTINCT ?country) AS ?totalCountries) (GROUP_CONCAT( ?countryName ; separator =", " ) AS ?list)
    WHERE {
       # ?country wdt:P31 ?class;
                wdt:P38 ?currency.
       # ?class wdt:P279* wd:Q6256.

       # get the label
       # ?currency sc:name ?currencyName.
       # ?country sc:name ?countryName.
    }

GROUP BY ?currency ?currencyName
HAVING ( COUNT(DISTINCT ?country) >= 2)
ORDER BY DESC (?totalCountries)
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('currency', 'http://www.wikidata.org/entity/Q4916'), ('currencyName', 'euro'), ('totalCountries', '25'), ('list', 'France, France, France, France, Germany, Germany, Estonia, Latvia, Latvia, Latvia, Slovakia, Slovakia, Slovakia, Slovenia, Andorra, Andorra, Cyprus, Cyprus, Malta, Malta, Monaco, Montenegro, Montenegro, Montenegro, Montenegro, Vatican City, San Marino, Ireland, Ireland, Ireland, Spain, Kingdom of the Netherlands, Kingdom of the Netherlands, Kingdom of the Netherlands, Belgium, Luxembourg, Finland, Finland, Finland, Lithuania, Italy, Italy, Austria, Austria, Austria, Greece, Greece, Portugal, Portugal, Portugal, Netherlands')]
# [('currency', 'http://www.wikidata.org/entity/Q4917'), ('currencyName', 'United States dollar'), ('totalCountries', '12'), ('list', 'Northern Mariana Islands, Liberia, Liberia, American Samoa, United States of America, United States of America, East Timor, East Timor, East Timor, Palau, Palau, Palau, Federated States of Micronesia, Federated States of Micronesia, Federated States of Micronesia, Marshall Islands, Marshall Islands, Marshall Islands, Ecuador, Ecuador, El Salvador, El Salvador, Panama, Zimbabwe, Zimbabwe, Zimbabwe')]
# [('currency', 'http://www.wikidata.org/entity/Q861690'), ('currencyName', 'West African CFA franc'), ('totalCountries', '8'), ('list', 'Guinea-Bissau, Guinea-Bissau, Ivory Coast, Ivory Coast, Niger, Niger, Niger, Senegal, Senegal, Mali, Mali, Mali, Togo, Togo, Benin, Benin, Burkina Faso, Burkina Faso, Burkina Faso')]
# [('currency', 'http://www.wikidata.org/entity/Q26365'), ('currencyName', 'Eastern Caribbean dollar'), ('totalCountries', '6'), ('list', 'Saint Vincent and the Grenadines, Saint Vincent and the Grenadines, Saint Vincent and the Grenadines, Saint Vincent and the Grenadines, Saint Lucia, Saint Lucia, Saint Lucia, Saint Lucia, Saint Kitts and Nevis, Saint Kitts and Nevis, Saint Kitts and Nevis, Saint Kitts and Nevis, Grenada, Grenada, Grenada, Grenada, Antigua and Barbuda, Antigua and Barbuda, Antigua and Barbuda, Antigua and Barbuda, Dominica, Dominica, Dominica')]
# [('currency', 'http://www.wikidata.org/entity/Q847739'), ('currencyName', 'Central African CFA franc'), ('totalCountries', '6'), ('list', 'Gabon, Cameroon, Cameroon, Chad, Chad, Chad, Central African Republic, Central African Republic, Central African Republic, Republic of the Congo, Republic of the Congo, Equatorial Guinea')]
# [('currency', 'http://www.wikidata.org/entity/Q259502'), ('currencyName', 'Australian dollar'), ('totalCountries', '4'), ('list', 'Australia, Australia, Australia, Tuvalu, Tuvalu, Tuvalu, Tuvalu, Nauru, Nauru, Nauru, Kiribati, Kiribati, Kiribati')]
# [('currency', 'http://www.wikidata.org/entity/Q199462'), ('currencyName', 'Egyptian pound'), ('totalCountries', '4'), ('list', 'Khedivate of Egypt, Sultanate of Egypt, Kingdom of Egypt, Egypt, Egypt, Egypt, Egypt, Egypt')]
# [('currency', 'http://www.wikidata.org/entity/Q181907'), ('currencyName', 'South African rand'), ('totalCountries', '3'), ('list', 'Lesotho, Lesotho, Lesotho, Namibia, Namibia, South Africa, South Africa')]
# [('currency', 'http://www.wikidata.org/entity/Q1472704'), ('currencyName', 'New Zealand dollar'), ('totalCountries', '3'), ('list', 'Cook Islands, Cook Islands, Niue, Niue, New Zealand, New Zealand, New Zealand, New Zealand')]
# [('currency', 'http://www.wikidata.org/entity/Q25224'), ('currencyName', 'pound sterling'), ('totalCountries', '3'), ('list', 'United Kingdom, United Kingdom, United Kingdom, United Kingdom, United Kingdom, Wales, British Empire, British Empire, British Empire, British Empire')]
# [('currency', 'http://www.wikidata.org/entity/Q25417'), ('currencyName', 'Danish krone'), ('totalCountries', '3'), ('list', 'Greenland, Greenland, Danish Realm, Danish Realm, Danish Realm, Denmark, Denmark, Denmark, Denmark, Denmark')]
# [('currency', 'http://www.wikidata.org/entity/Q199471'), ('currencyName', 'Afghan afghani'), ('totalCountries', '3'), ('list', 'Islamic Republic of Afghanistan, Afghanistan, Afghanistan, Afghanistan, Islamic Emirate of Afghanistan')]
# [('currency', 'http://www.wikidata.org/entity/Q130498'), ('currencyName', 'Armenian dram'), ('totalCountries', '2'), ('list', 'Republic of Artsakh, Armenia')]
# [('currency', 'http://www.wikidata.org/entity/Q206243'), ('currencyName', 'birr'), ('totalCountries', '2'), ('list', 'Ethiopia, Ethiopia, Ethiopia, Ethiopian Empire')]
# [('currency', 'http://www.wikidata.org/entity/Q952064'), ('currencyName', 'Roman currency'), ('totalCountries', '2'), ('list', 'Roman Empire, Western Roman Empire (395-476 AD)')]
# [('currency', 'http://www.wikidata.org/entity/Q184172'), ('currencyName', 'French franc'), ('totalCountries', '2'), ('list', 'French colonial empire, First French Empire')]
# [('currency', 'http://www.wikidata.org/entity/Q25344'), ('currencyName', 'Swiss franc'), ('totalCountries', '2'), ('list', 'Liechtenstein, Liechtenstein, Switzerland, Switzerland')]
# [('currency', 'http://www.wikidata.org/entity/Q191068'), ('currencyName', 'Faroese króna'), ('totalCountries', '2'), ('list', 'Danish Realm, Danish Realm, Danish Realm, Faroe Islands')]
# [('currency', 'http://www.wikidata.org/entity/Q172872'), ('currencyName', 'Turkish lira'), ('totalCountries', '2'), ('list', 'Turkish Republic of Northern Cyprus, Turkey, Turkey, Turkey, Turkey, Turkey')]
# [('currency', 'http://www.wikidata.org/entity/Q8146'), ('currencyName', 'Japanese yen'), ('totalCountries', '2'), ('list', 'Japan, Japan, Japan, Empire of Japan')]
# [('currency', 'http://www.wikidata.org/entity/Q41044'), ('currencyName', 'Russian ruble'), ('totalCountries', '2'), ('list', 'Russia, South Ossetia')]
# [('currency', 'http://www.wikidata.org/entity/Q191830'), ('currencyName', 'dinar'), ('totalCountries', '2'), ('list', 'Timurid Empire, Fatimid Caliphate')]
# [('currency', 'http://www.wikidata.org/entity/Q188608'), ('currencyName', 'Iranian rial'), ('totalCountries', '2'), ('list', 'Pahlavi Dynasty, Iran, Iran')]
# 23

# %%
 #Add distinct on list (CANDIDATE FINAL QUERY)
queryString = """    
    SELECT ?currency ?currencyName (COUNT(DISTINCT ?country) AS ?totalCountries) (GROUP_CONCAT(DISTINCT ?countryName ; separator =", " ) AS ?list)
    WHERE {
       # ?country wdt:P31 ?class;
                wdt:P38 ?currency.
       # ?class wdt:P279* wd:Q6256.

       # get the label
       # ?currency sc:name ?currencyName.
       # ?country sc:name ?countryName.
    }

GROUP BY ?currency ?currencyName
HAVING ( COUNT(DISTINCT ?country) >= 2)
ORDER BY DESC (?totalCountries)
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('currency', 'http://www.wikidata.org/entity/Q4916'), ('currencyName', 'euro'), ('totalCountries', '25'), ('list', 'Andorra, Austria, Belgium, Cyprus, Estonia, Finland, France, Germany, Greece, Ireland, Italy, Kingdom of the Netherlands, Latvia, Lithuania, Luxembourg, Malta, Monaco, Montenegro, Netherlands, Portugal, San Marino, Slovakia, Slovenia, Spain, Vatican City')]
# [('currency', 'http://www.wikidata.org/entity/Q4917'), ('currencyName', 'United States dollar'), ('totalCountries', '12'), ('list', 'American Samoa, East Timor, Ecuador, El Salvador, Federated States of Micronesia, Liberia, Marshall Islands, Northern Mariana Islands, Palau, Panama, United States of America, Zimbabwe')]
# [('currency', 'http://www.wikidata.org/entity/Q861690'), ('currencyName', 'West African CFA franc'), ('totalCountries', '8'), ('list', 'Benin, Burkina Faso, Guinea-Bissau, Ivory Coast, Mali, Niger, Senegal, Togo')]
# [('currency', 'http://www.wikidata.org/entity/Q26365'), ('currencyName', 'Eastern Caribbean dollar'), ('totalCountries', '6'), ('list', 'Antigua and Barbuda, Dominica, Grenada, Saint Kitts and Nevis, Saint Lucia, Saint Vincent and the Grenadines')]
# [('currency', 'http://www.wikidata.org/entity/Q847739'), ('currencyName', 'Central African CFA franc'), ('totalCountries', '6'), ('list', 'Cameroon, Central African Republic, Chad, Equatorial Guinea, Gabon, Republic of the Congo')]
# [('currency', 'http://www.wikidata.org/entity/Q259502'), ('currencyName', 'Australian dollar'), ('totalCountries', '4'), ('list', 'Australia, Kiribati, Nauru, Tuvalu')]
# [('currency', 'http://www.wikidata.org/entity/Q199462'), ('currencyName', 'Egyptian pound'), ('totalCountries', '4'), ('list', 'Egypt, Khedivate of Egypt, Kingdom of Egypt, Sultanate of Egypt')]
# [('currency', 'http://www.wikidata.org/entity/Q181907'), ('currencyName', 'South African rand'), ('totalCountries', '3'), ('list', 'Lesotho, Namibia, South Africa')]
# [('currency', 'http://www.wikidata.org/entity/Q1472704'), ('currencyName', 'New Zealand dollar'), ('totalCountries', '3'), ('list', 'Cook Islands, New Zealand, Niue')]
# [('currency', 'http://www.wikidata.org/entity/Q25224'), ('currencyName', 'pound sterling'), ('totalCountries', '3'), ('list', 'British Empire, United Kingdom, Wales')]
# [('currency', 'http://www.wikidata.org/entity/Q25417'), ('currencyName', 'Danish krone'), ('totalCountries', '3'), ('list', 'Danish Realm, Denmark, Greenland')]
# [('currency', 'http://www.wikidata.org/entity/Q199471'), ('currencyName', 'Afghan afghani'), ('totalCountries', '3'), ('list', 'Afghanistan, Islamic Emirate of Afghanistan, Islamic Republic of Afghanistan')]
# [('currency', 'http://www.wikidata.org/entity/Q130498'), ('currencyName', 'Armenian dram'), ('totalCountries', '2'), ('list', 'Armenia, Republic of Artsakh')]
# [('currency', 'http://www.wikidata.org/entity/Q206243'), ('currencyName', 'birr'), ('totalCountries', '2'), ('list', 'Ethiopia, Ethiopian Empire')]
# [('currency', 'http://www.wikidata.org/entity/Q952064'), ('currencyName', 'Roman currency'), ('totalCountries', '2'), ('list', 'Roman Empire, Western Roman Empire (395-476 AD)')]
# [('currency', 'http://www.wikidata.org/entity/Q184172'), ('currencyName', 'French franc'), ('totalCountries', '2'), ('list', 'First French Empire, French colonial empire')]
# [('currency', 'http://www.wikidata.org/entity/Q25344'), ('currencyName', 'Swiss franc'), ('totalCountries', '2'), ('list', 'Liechtenstein, Switzerland')]
# [('currency', 'http://www.wikidata.org/entity/Q191068'), ('currencyName', 'Faroese króna'), ('totalCountries', '2'), ('list', 'Danish Realm, Faroe Islands')]
# [('currency', 'http://www.wikidata.org/entity/Q172872'), ('currencyName', 'Turkish lira'), ('totalCountries', '2'), ('list', 'Turkey, Turkish Republic of Northern Cyprus')]
# [('currency', 'http://www.wikidata.org/entity/Q8146'), ('currencyName', 'Japanese yen'), ('totalCountries', '2'), ('list', 'Empire of Japan, Japan')]
# [('currency', 'http://www.wikidata.org/entity/Q41044'), ('currencyName', 'Russian ruble'), ('totalCountries', '2'), ('list', 'Russia, South Ossetia')]
# [('currency', 'http://www.wikidata.org/entity/Q191830'), ('currencyName', 'dinar'), ('totalCountries', '2'), ('list', 'Fatimid Caliphate, Timurid Empire')]
# [('currency', 'http://www.wikidata.org/entity/Q188608'), ('currencyName', 'Iranian rial'), ('totalCountries', '2'), ('list', 'Iran, Pahlavi Dynasty')]
# 23

# %%
#different version starting from currencies and country property 
queryString = """    
SELECT ?currency ?currencyName (COUNT(DISTINCT ?country) AS ?totalCountries) (GROUP_CONCAT(DISTINCT ?countryName ; separator =", " ) AS ?list)
WHERE {
      # ?currency wdt:P31 wd:Q8142.
      # ?currency wdt:P17 ?country.
      # get the label
      # ?currency sc:name ?currencyName.
      # ?country sc:name ?countryName.
}
GROUP BY ?currency ?currencyName
HAVING ( COUNT(DISTINCT ?country) >= 2)
ORDER BY DESC (?totalCountries)
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('currency', 'http://www.wikidata.org/entity/Q4916'), ('currencyName', 'euro'), ('totalCountries', '23'), ('list', 'Andorra, Austria, Belgium, Cyprus, Estonia, Finland, France, Germany, Greece, Ireland, Italy, Latvia, Lithuania, Luxembourg, Malta, Monaco, Netherlands, Portugal, San Marino, Slovakia, Slovenia, Spain, Vatican City')]
# [('currency', 'http://www.wikidata.org/entity/Q189097'), ('currencyName', 'peseta'), ('totalCountries', '9'), ('list', 'Andorra, Captaincy General of Cuba, Captaincy General of Puerto Rico, Captaincy General of the Philippines, Equatorial Guinea, Ifni, Spain, Spanish Protectorate in Morocco, Western Sahara')]
# [('currency', 'http://www.wikidata.org/entity/Q26365'), ('currencyName', 'Eastern Caribbean dollar'), ('totalCountries', '8'), ('list', 'Anguilla, Antigua and Barbuda, Dominica, Grenada, Montserrat, Saint Kitts and Nevis, Saint Lucia, Saint Vincent and the Grenadines')]
# [('currency', 'http://www.wikidata.org/entity/Q861690'), ('currencyName', 'West African CFA franc'), ('totalCountries', '8'), ('list', 'Benin, Burkina Faso, Guinea-Bissau, Ivory Coast, Mali, Niger, Senegal, Togo')]
# [('currency', 'http://www.wikidata.org/entity/Q847739'), ('currencyName', 'Central African CFA franc'), ('totalCountries', '6'), ('list', 'Cameroon, Central African Republic, Chad, Equatorial Guinea, Gabon, Republic of the Congo')]
# [('currency', 'http://www.wikidata.org/entity/Q3973271'), ('currencyName', 'Palestine pound'), ('totalCountries', '4'), ('list', 'Emirate of Transjordan, Israel, Mandatory Palestine, West Bank')]
# [('currency', 'http://www.wikidata.org/entity/Q5639749'), ('currencyName', 'Haitian livre'), ('totalCountries', '4'), ('list', 'First Empire of Haiti, Haiti, Saint-Domingue, State of Haiti')]
# [('currency', 'http://www.wikidata.org/entity/Q1072248'), ('currencyName', 'Rwanda and Burundi franc'), ('totalCountries', '3'), ('list', 'Burundi, Ruanda-Urundi, Rwanda')]
# [('currency', 'http://www.wikidata.org/entity/Q804170'), ('currencyName', 'Baiocco'), ('totalCountries', '3'), ('list', 'Papal States, Roman Republic')]
# [('currency', 'http://www.wikidata.org/entity/Q942092'), ('currencyName', 'British West Indies dollar'), ('totalCountries', '3'), ('list', 'British Guiana, British West Indies, Jamaica')]
# [('currency', 'http://www.wikidata.org/entity/Q1415602'), ('currencyName', 'Kopeck'), ('totalCountries', '3'), ('list', 'Russia, Soviet Union, Ukraine')]
# [('currency', 'http://www.wikidata.org/entity/Q2329625'), ('currencyName', 'Austrian krone'), ('totalCountries', '3'), ('list', 'First Republic of Austria, Liechtenstein, Republic of German-Austria')]
# [('currency', 'http://www.wikidata.org/entity/Q184172'), ('currencyName', 'French franc'), ('totalCountries', '3'), ('list', 'Andorra, France, Monaco')]
# [('currency', 'http://www.wikidata.org/entity/Q10924925'), ('currencyName', 'Sichuan Rupee'), ('totalCountries', '3'), ('list', "People's Republic of China, Qing dynasty, Republic of China 1912–1949")]
# [('currency', 'http://www.wikidata.org/entity/Q373429'), ('currencyName', 'Yugoslav dinar'), ('totalCountries', '3'), ('list', 'Federal Republic of Yugoslavia, Kingdom of Yugoslavia, Socialist Federal Republic of Yugoslavia')]
# [('currency', 'http://www.wikidata.org/entity/Q1983857'), ('currencyName', 'Abkhazian apsar'), ('totalCountries', '2'), ('list', 'Georgia, Republic of Abkhazia')]
# [('currency', 'http://www.wikidata.org/entity/Q19953480'), ('currencyName', 'chuzan-tsuho'), ('totalCountries', '2'), ('list', 'Chūzan, Ryukyu Kingdom')]
# [('currency', 'http://www.wikidata.org/entity/Q1509365'), ('currencyName', 'gold franc'), ('totalCountries', '2'), ('list', 'International Telecommunication Union, Universal Postal Union')]
# [('currency', 'http://www.wikidata.org/entity/Q25344'), ('currencyName', 'Swiss franc'), ('totalCountries', '2'), ('list', 'Liechtenstein, Switzerland')]
# [('currency', 'http://www.wikidata.org/entity/Q2273865'), ('currencyName', 'Italian Somaliland somalo'), ('totalCountries', '2'), ('list', 'Somalia, Trust Territory of Somalia')]
# [('currency', 'http://www.wikidata.org/entity/Q1852872'), ('currencyName', 'New Hebrides franc'), ('totalCountries', '2'), ('list', 'New Hebrides, Vanuatu')]
# [('currency', 'http://www.wikidata.org/entity/Q722411'), ('currencyName', 'Hungarian adópengő'), ('totalCountries', '2'), ('list', 'Kingdom of Hungary, Republic of Hungary')]
# [('currency', 'http://www.wikidata.org/entity/Q4060587'), ('currencyName', 'Franga'), ('totalCountries', '2'), ('list', 'Albanian Republic, Kingdom of Albania')]
# [('currency', 'http://www.wikidata.org/entity/Q2348843'), ('currencyName', 'Cambodian tical'), ('totalCountries', '2'), ('list', 'Cambodia, Siam')]
# [('currency', 'http://www.wikidata.org/entity/Q786009'), ('currencyName', 'Montenegrin perper'), ('totalCountries', '2'), ('list', 'Kingdom of Montenegro, Principality of Montenegro')]
# [('currency', 'http://www.wikidata.org/entity/Q522701'), ('currencyName', 'Netherlands Antillean guilder'), ('totalCountries', '2'), ('list', 'Curaçao, Sint Maarten')]
# [('currency', 'http://www.wikidata.org/entity/Q172872'), ('currencyName', 'Turkish lira'), ('totalCountries', '2'), ('list', 'Turkey, Turkish Republic of Northern Cyprus')]
# [('currency', 'http://www.wikidata.org/entity/Q106615825'), ('currencyName', 'valadia'), ('totalCountries', '2'), ('list', 'Kingdom of Portugal, Marinid Dynasty')]
# [('currency', 'http://www.wikidata.org/entity/Q31015'), ('currencyName', 'Hong Kong dollar'), ('totalCountries', '2'), ('list', "Hong Kong, People's Republic of China")]
# [('currency', 'http://www.wikidata.org/entity/Q56302633'), ('currencyName', 'Ouguiya (1973-2017)'), ('totalCountries', '2'), ('list', 'Mauritania, Sahrawi Arab Democratic Republic')]
# [('currency', 'http://www.wikidata.org/entity/Q207669'), ('currencyName', 'Hungarian pengő'), ('totalCountries', '2'), ('list', 'Kingdom of Hungary, Republic of Hungary')]
# [('currency', 'http://www.wikidata.org/entity/Q208730'), ('currencyName', 'Austrian schilling'), ('totalCountries', '2'), ('list', 'Austria, First Republic of Austria')]
# [('currency', 'http://www.wikidata.org/entity/Q16068'), ('currencyName', 'Deutsche Mark'), ('totalCountries', '2'), ('list', 'Germany, West Germany')]
# [('currency', 'http://www.wikidata.org/entity/Q3658911'), ('currencyName', 'Carlino'), ('totalCountries', '2'), ('list', 'Italy, Malta')]
# [('currency', 'http://www.wikidata.org/entity/Q306306'), ('currencyName', 'Austro-Hungarian gulden'), ('totalCountries', '2'), ('list', 'Austria-Hungary, Austrian Empire')]
# [('currency', 'http://www.wikidata.org/entity/Q618653'), ('currencyName', 'North Yemeni rial'), ('totalCountries', '2'), ('list', 'Mutawakkilite Kingdom of Yemen, Yemen Arab Republic')]
# [('currency', 'http://www.wikidata.org/entity/Q56374559'), ('currencyName', 'Manat'), ('totalCountries', '2'), ('list', 'Azerbaijan, Turkmenistan')]
# [('currency', 'http://www.wikidata.org/entity/Q4124886'), ('currencyName', 'Red Army won'), ('totalCountries', '2'), ('list', 'North Korea, Soviet Union')]
# [('currency', 'http://www.wikidata.org/entity/Q5527593'), ('currencyName', 'Gaucho'), ('totalCountries', '2'), ('list', 'Argentina, Brazil')]
# [('currency', 'http://www.wikidata.org/entity/Q737779'), ('currencyName', 'Caribbean guilder'), ('totalCountries', '2'), ('list', 'Curaçao, Sint Maarten')]
# [('currency', 'http://www.wikidata.org/entity/Q868106'), ('currencyName', 'Korean yen'), ('totalCountries', '2'), ('list', 'Korea under Japanese rule, Korean Empire')]
# 41

# %%
#return objects linked by country property to korean yen
queryString = """
SELECT ?o ?name
WHERE {
   wd:Q868106 wdt:P17 ?o.
   # ?o sc:name ?name.
   
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('o', 'http://www.wikidata.org/entity/Q503585'), ('name', 'Korea under Japanese rule')]
# [('o', 'http://www.wikidata.org/entity/Q28233'), ('name', 'Korean Empire')]
# 2

# %%
#return what korean empire is instance of
queryString = """
SELECT ?o ?name
WHERE {
   wd:Q28233 wdt:P31 ?o.
   # ?o sc:name ?name.
   
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('o', 'http://www.wikidata.org/entity/Q3024240'), ('name', 'historical country')]
# 1

# %%
#different version starting from currencies and country property not including historical countries
queryString = """    
    SELECT ?currency ?currencyName (COUNT(DISTINCT ?country) AS ?totalCountries) (GROUP_CONCAT(DISTINCT ?countryName ; separator =", " ) AS ?list)
    WHERE {
       # ?currency wdt:P31 wd:Q8142.
       # ?currency wdt:P17 ?country.
       
       # get the label
       # ?currency sc:name ?currencyName.
       # ?country sc:name ?countryName.
       FILTER(NOT EXISTS {?country wdt:P31 wd:Q3024240})
    }

GROUP BY ?currency ?currencyName
HAVING ( COUNT(DISTINCT ?country) >= 2)
ORDER BY DESC (?totalCountries)
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('currency', 'http://www.wikidata.org/entity/Q4916'), ('currencyName', 'euro'), ('totalCountries', '23'), ('list', 'Andorra, Austria, Belgium, Cyprus, Estonia, Finland, France, Germany, Greece, Ireland, Italy, Latvia, Lithuania, Luxembourg, Malta, Monaco, Netherlands, Portugal, San Marino, Slovakia, Slovenia, Spain, Vatican City')]
# [('currency', 'http://www.wikidata.org/entity/Q189097'), ('currencyName', 'peseta'), ('totalCountries', '9'), ('list', 'Andorra, Captaincy General of Cuba, Captaincy General of Puerto Rico, Captaincy General of the Philippines, Equatorial Guinea, Ifni, Spain, Spanish Protectorate in Morocco, Western Sahara')]
# [('currency', 'http://www.wikidata.org/entity/Q26365'), ('currencyName', 'Eastern Caribbean dollar'), ('totalCountries', '8'), ('list', 'Anguilla, Antigua and Barbuda, Dominica, Grenada, Montserrat, Saint Kitts and Nevis, Saint Lucia, Saint Vincent and the Grenadines')]
# [('currency', 'http://www.wikidata.org/entity/Q861690'), ('currencyName', 'West African CFA franc'), ('totalCountries', '8'), ('list', 'Benin, Burkina Faso, Guinea-Bissau, Ivory Coast, Mali, Niger, Senegal, Togo')]
# [('currency', 'http://www.wikidata.org/entity/Q847739'), ('currencyName', 'Central African CFA franc'), ('totalCountries', '6'), ('list', 'Cameroon, Central African Republic, Chad, Equatorial Guinea, Gabon, Republic of the Congo')]
# [('currency', 'http://www.wikidata.org/entity/Q3973271'), ('currencyName', 'Palestine pound'), ('totalCountries', '4'), ('list', 'Emirate of Transjordan, Israel, Mandatory Palestine, West Bank')]
# [('currency', 'http://www.wikidata.org/entity/Q942092'), ('currencyName', 'British West Indies dollar'), ('totalCountries', '3'), ('list', 'British Guiana, British West Indies, Jamaica')]
# [('currency', 'http://www.wikidata.org/entity/Q184172'), ('currencyName', 'French franc'), ('totalCountries', '3'), ('list', 'Andorra, France, Monaco')]
# [('currency', 'http://www.wikidata.org/entity/Q1983857'), ('currencyName', 'Abkhazian apsar'), ('totalCountries', '2'), ('list', 'Georgia, Republic of Abkhazia')]
# [('currency', 'http://www.wikidata.org/entity/Q1072248'), ('currencyName', 'Rwanda and Burundi franc'), ('totalCountries', '2'), ('list', 'Burundi, Rwanda')]
# [('currency', 'http://www.wikidata.org/entity/Q1509365'), ('currencyName', 'gold franc'), ('totalCountries', '2'), ('list', 'International Telecommunication Union, Universal Postal Union')]
# [('currency', 'http://www.wikidata.org/entity/Q25344'), ('currencyName', 'Swiss franc'), ('totalCountries', '2'), ('list', 'Liechtenstein, Switzerland')]
# [('currency', 'http://www.wikidata.org/entity/Q2273865'), ('currencyName', 'Italian Somaliland somalo'), ('totalCountries', '2'), ('list', 'Somalia, Trust Territory of Somalia')]
# [('currency', 'http://www.wikidata.org/entity/Q1415602'), ('currencyName', 'Kopeck'), ('totalCountries', '2'), ('list', 'Russia, Ukraine')]
# [('currency', 'http://www.wikidata.org/entity/Q522701'), ('currencyName', 'Netherlands Antillean guilder'), ('totalCountries', '2'), ('list', 'Curaçao, Sint Maarten')]
# [('currency', 'http://www.wikidata.org/entity/Q172872'), ('currencyName', 'Turkish lira'), ('totalCountries', '2'), ('list', 'Turkey, Turkish Republic of Northern Cyprus')]
# [('currency', 'http://www.wikidata.org/entity/Q31015'), ('currencyName', 'Hong Kong dollar'), ('totalCountries', '2'), ('list', "Hong Kong, People's Republic of China")]
# [('currency', 'http://www.wikidata.org/entity/Q56302633'), ('currencyName', 'Ouguiya (1973-2017)'), ('totalCountries', '2'), ('list', 'Mauritania, Sahrawi Arab Democratic Republic')]
# [('currency', 'http://www.wikidata.org/entity/Q10924925'), ('currencyName', 'Sichuan Rupee'), ('totalCountries', '2'), ('list', "People's Republic of China, Qing dynasty")]
# [('currency', 'http://www.wikidata.org/entity/Q5639749'), ('currencyName', 'Haitian livre'), ('totalCountries', '2'), ('list', 'Haiti, Saint-Domingue')]
# [('currency', 'http://www.wikidata.org/entity/Q3658911'), ('currencyName', 'Carlino'), ('totalCountries', '2'), ('list', 'Italy, Malta')]
# [('currency', 'http://www.wikidata.org/entity/Q56374559'), ('currencyName', 'Manat'), ('totalCountries', '2'), ('list', 'Azerbaijan, Turkmenistan')]
# [('currency', 'http://www.wikidata.org/entity/Q5527593'), ('currencyName', 'Gaucho'), ('totalCountries', '2'), ('list', 'Argentina, Brazil')]
# [('currency', 'http://www.wikidata.org/entity/Q737779'), ('currencyName', 'Caribbean guilder'), ('totalCountries', '2'), ('list', 'Curaçao, Sint Maarten')]
# 24

# %%
#different filter
queryString = """    
    SELECT ?currency ?currencyName (COUNT(DISTINCT ?country) AS ?totalCountries) (GROUP_CONCAT(DISTINCT ?countryName ; separator =", " ) AS ?list)
    WHERE {
       # ?currency wdt:P31 wd:Q8142.
       # ?currency wdt:P17 ?country.
       # ?country wdt:P31+ ?class.
       # get the label
       # ?currency sc:name ?currencyName.
       # ?country sc:name ?countryName.
       FILTER(?class != wd:Q3024240)
    }

GROUP BY ?currency ?currencyName
HAVING ( COUNT(DISTINCT ?country) >= 2)
ORDER BY DESC (?totalCountries)
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('currency', 'http://www.wikidata.org/entity/Q4916'), ('currencyName', 'euro'), ('totalCountries', '23'), ('list', 'Andorra, Austria, Belgium, Cyprus, Estonia, Finland, France, Germany, Greece, Ireland, Italy, Latvia, Lithuania, Luxembourg, Malta, Monaco, Netherlands, Portugal, San Marino, Slovakia, Slovenia, Spain, Vatican City')]
# [('currency', 'http://www.wikidata.org/entity/Q189097'), ('currencyName', 'peseta'), ('totalCountries', '9'), ('list', 'Andorra, Captaincy General of Cuba, Captaincy General of Puerto Rico, Captaincy General of the Philippines, Equatorial Guinea, Ifni, Spain, Spanish Protectorate in Morocco, Western Sahara')]
# [('currency', 'http://www.wikidata.org/entity/Q26365'), ('currencyName', 'Eastern Caribbean dollar'), ('totalCountries', '8'), ('list', 'Anguilla, Antigua and Barbuda, Dominica, Grenada, Montserrat, Saint Kitts and Nevis, Saint Lucia, Saint Vincent and the Grenadines')]
# [('currency', 'http://www.wikidata.org/entity/Q861690'), ('currencyName', 'West African CFA franc'), ('totalCountries', '8'), ('list', 'Benin, Burkina Faso, Guinea-Bissau, Ivory Coast, Mali, Niger, Senegal, Togo')]
# [('currency', 'http://www.wikidata.org/entity/Q847739'), ('currencyName', 'Central African CFA franc'), ('totalCountries', '6'), ('list', 'Cameroon, Central African Republic, Chad, Equatorial Guinea, Gabon, Republic of the Congo')]
# [('currency', 'http://www.wikidata.org/entity/Q3973271'), ('currencyName', 'Palestine pound'), ('totalCountries', '4'), ('list', 'Emirate of Transjordan, Israel, Mandatory Palestine, West Bank')]
# [('currency', 'http://www.wikidata.org/entity/Q1072248'), ('currencyName', 'Rwanda and Burundi franc'), ('totalCountries', '3'), ('list', 'Burundi, Ruanda-Urundi, Rwanda')]
# [('currency', 'http://www.wikidata.org/entity/Q942092'), ('currencyName', 'British West Indies dollar'), ('totalCountries', '3'), ('list', 'British Guiana, British West Indies, Jamaica')]
# [('currency', 'http://www.wikidata.org/entity/Q184172'), ('currencyName', 'French franc'), ('totalCountries', '3'), ('list', 'Andorra, France, Monaco')]
# [('currency', 'http://www.wikidata.org/entity/Q10924925'), ('currencyName', 'Sichuan Rupee'), ('totalCountries', '3'), ('list', "People's Republic of China, Qing dynasty, Republic of China 1912–1949")]
# [('currency', 'http://www.wikidata.org/entity/Q1983857'), ('currencyName', 'Abkhazian apsar'), ('totalCountries', '2'), ('list', 'Georgia, Republic of Abkhazia')]
# [('currency', 'http://www.wikidata.org/entity/Q19953480'), ('currencyName', 'chuzan-tsuho'), ('totalCountries', '2'), ('list', 'Chūzan, Ryukyu Kingdom')]
# [('currency', 'http://www.wikidata.org/entity/Q1509365'), ('currencyName', 'gold franc'), ('totalCountries', '2'), ('list', 'International Telecommunication Union, Universal Postal Union')]
# [('currency', 'http://www.wikidata.org/entity/Q804170'), ('currencyName', 'Baiocco'), ('totalCountries', '2'), ('list', 'Roman Republic')]
# [('currency', 'http://www.wikidata.org/entity/Q25344'), ('currencyName', 'Swiss franc'), ('totalCountries', '2'), ('list', 'Liechtenstein, Switzerland')]
# [('currency', 'http://www.wikidata.org/entity/Q2273865'), ('currencyName', 'Italian Somaliland somalo'), ('totalCountries', '2'), ('list', 'Somalia, Trust Territory of Somalia')]
# [('currency', 'http://www.wikidata.org/entity/Q1852872'), ('currencyName', 'New Hebrides franc'), ('totalCountries', '2'), ('list', 'New Hebrides, Vanuatu')]
# [('currency', 'http://www.wikidata.org/entity/Q2348843'), ('currencyName', 'Cambodian tical'), ('totalCountries', '2'), ('list', 'Cambodia, Siam')]
# [('currency', 'http://www.wikidata.org/entity/Q1415602'), ('currencyName', 'Kopeck'), ('totalCountries', '2'), ('list', 'Russia, Ukraine')]
# [('currency', 'http://www.wikidata.org/entity/Q786009'), ('currencyName', 'Montenegrin perper'), ('totalCountries', '2'), ('list', 'Kingdom of Montenegro, Principality of Montenegro')]
# [('currency', 'http://www.wikidata.org/entity/Q522701'), ('currencyName', 'Netherlands Antillean guilder'), ('totalCountries', '2'), ('list', 'Curaçao, Sint Maarten')]
# [('currency', 'http://www.wikidata.org/entity/Q172872'), ('currencyName', 'Turkish lira'), ('totalCountries', '2'), ('list', 'Turkey, Turkish Republic of Northern Cyprus')]
# [('currency', 'http://www.wikidata.org/entity/Q106615825'), ('currencyName', 'valadia'), ('totalCountries', '2'), ('list', 'Kingdom of Portugal, Marinid Dynasty')]
# [('currency', 'http://www.wikidata.org/entity/Q31015'), ('currencyName', 'Hong Kong dollar'), ('totalCountries', '2'), ('list', "Hong Kong, People's Republic of China")]
# [('currency', 'http://www.wikidata.org/entity/Q56302633'), ('currencyName', 'Ouguiya (1973-2017)'), ('totalCountries', '2'), ('list', 'Mauritania, Sahrawi Arab Democratic Republic')]
# [('currency', 'http://www.wikidata.org/entity/Q5639749'), ('currencyName', 'Haitian livre'), ('totalCountries', '2'), ('list', 'Haiti, Saint-Domingue')]
# [('currency', 'http://www.wikidata.org/entity/Q16068'), ('currencyName', 'Deutsche Mark'), ('totalCountries', '2'), ('list', 'Germany, West Germany')]
# [('currency', 'http://www.wikidata.org/entity/Q3658911'), ('currencyName', 'Carlino'), ('totalCountries', '2'), ('list', 'Italy, Malta')]
# [('currency', 'http://www.wikidata.org/entity/Q56374559'), ('currencyName', 'Manat'), ('totalCountries', '2'), ('list', 'Azerbaijan, Turkmenistan')]
# [('currency', 'http://www.wikidata.org/entity/Q5527593'), ('currencyName', 'Gaucho'), ('totalCountries', '2'), ('list', 'Argentina, Brazil')]
# [('currency', 'http://www.wikidata.org/entity/Q737779'), ('currencyName', 'Caribbean guilder'), ('totalCountries', '2'), ('list', 'Curaçao, Sint Maarten')]
# 31

# %%
#return properties for Carlino currency
queryString = """
SELECT DISTINCT ?p ?name
WHERE {
   # bind something
   wd:Q3658911 ?p ?obj .
   # get the label
   # ?p sc:name ?name.
}
LIMIT 500
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P138'), ('name', 'named after')]
# [('p', 'http://www.wikidata.org/prop/direct/P17'), ('name', 'country')]
# [('p', 'http://www.wikidata.org/prop/direct/P18'), ('name', 'image')]
# [('p', 'http://www.wikidata.org/prop/direct/P2671'), ('name', 'Google Knowledge Graph ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('name', 'instance of')]
# [('p', 'http://www.wikidata.org/prop/direct/P373'), ('name', 'Commons category')]
# [('p', 'http://www.wikidata.org/prop/direct/P571'), ('name', 'inception')]
# [('p', 'http://www.wikidata.org/prop/direct/P582'), ('name', 'end time')]
# [('p', 'http://www.wikidata.org/prop/direct/P935'), ('name', 'Commons gallery')]
# 9

# %%
#return end time for Carlino currency
queryString = """
SELECT DISTINCT ?obj ?name
WHERE {
   # bind something
   wd:Q3658911 wdt:P582 ?obj .
}
LIMIT 500
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('obj', '1861-01-01T00:00:00Z')]
# 1

# %%
#different filter
queryString = """    
    SELECT ?currency ?currencyName (COUNT(DISTINCT ?country) AS ?totalCountries) (GROUP_CONCAT(DISTINCT ?countryName ; separator =", " ) AS ?list)
    WHERE {
       # ?currency wdt:P31 wd:Q8142.
       # ?currency wdt:P17 ?country.
       # ?country wdt:P31+ ?class.
       # get the label
       # ?currency sc:name ?currencyName.
       # ?country sc:name ?countryName.
       FILTER(NOT EXISTS {?currency wdt:P582 ?date })
    }

GROUP BY ?currency ?currencyName
HAVING ( COUNT(DISTINCT ?country) >= 2)
ORDER BY DESC (?totalCountries)
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('currency', 'http://www.wikidata.org/entity/Q4916'), ('currencyName', 'euro'), ('totalCountries', '23'), ('list', 'Andorra, Austria, Belgium, Cyprus, Estonia, Finland, France, Germany, Greece, Ireland, Italy, Latvia, Lithuania, Luxembourg, Malta, Monaco, Netherlands, Portugal, San Marino, Slovakia, Slovenia, Spain, Vatican City')]
# [('currency', 'http://www.wikidata.org/entity/Q26365'), ('currencyName', 'Eastern Caribbean dollar'), ('totalCountries', '8'), ('list', 'Anguilla, Antigua and Barbuda, Dominica, Grenada, Montserrat, Saint Kitts and Nevis, Saint Lucia, Saint Vincent and the Grenadines')]
# [('currency', 'http://www.wikidata.org/entity/Q861690'), ('currencyName', 'West African CFA franc'), ('totalCountries', '8'), ('list', 'Benin, Burkina Faso, Guinea-Bissau, Ivory Coast, Mali, Niger, Senegal, Togo')]
# [('currency', 'http://www.wikidata.org/entity/Q847739'), ('currencyName', 'Central African CFA franc'), ('totalCountries', '6'), ('list', 'Cameroon, Central African Republic, Chad, Equatorial Guinea, Gabon, Republic of the Congo')]
# [('currency', 'http://www.wikidata.org/entity/Q5639749'), ('currencyName', 'Haitian livre'), ('totalCountries', '4'), ('list', 'First Empire of Haiti, Haiti, Saint-Domingue, State of Haiti')]
# [('currency', 'http://www.wikidata.org/entity/Q804170'), ('currencyName', 'Baiocco'), ('totalCountries', '3'), ('list', 'Papal States, Roman Republic')]
# [('currency', 'http://www.wikidata.org/entity/Q1415602'), ('currencyName', 'Kopeck'), ('totalCountries', '3'), ('list', 'Russia, Soviet Union, Ukraine')]
# [('currency', 'http://www.wikidata.org/entity/Q1983857'), ('currencyName', 'Abkhazian apsar'), ('totalCountries', '2'), ('list', 'Georgia, Republic of Abkhazia')]
# [('currency', 'http://www.wikidata.org/entity/Q19953480'), ('currencyName', 'chuzan-tsuho'), ('totalCountries', '2'), ('list', 'Chūzan, Ryukyu Kingdom')]
# [('currency', 'http://www.wikidata.org/entity/Q25344'), ('currencyName', 'Swiss franc'), ('totalCountries', '2'), ('list', 'Liechtenstein, Switzerland')]
# [('currency', 'http://www.wikidata.org/entity/Q722411'), ('currencyName', 'Hungarian adópengő'), ('totalCountries', '2'), ('list', 'Kingdom of Hungary, Republic of Hungary')]
# [('currency', 'http://www.wikidata.org/entity/Q2348843'), ('currencyName', 'Cambodian tical'), ('totalCountries', '2'), ('list', 'Cambodia, Siam')]
# [('currency', 'http://www.wikidata.org/entity/Q522701'), ('currencyName', 'Netherlands Antillean guilder'), ('totalCountries', '2'), ('list', 'Curaçao, Sint Maarten')]
# [('currency', 'http://www.wikidata.org/entity/Q172872'), ('currencyName', 'Turkish lira'), ('totalCountries', '2'), ('list', 'Turkey, Turkish Republic of Northern Cyprus')]
# [('currency', 'http://www.wikidata.org/entity/Q106615825'), ('currencyName', 'valadia'), ('totalCountries', '2'), ('list', 'Kingdom of Portugal, Marinid Dynasty')]
# [('currency', 'http://www.wikidata.org/entity/Q31015'), ('currencyName', 'Hong Kong dollar'), ('totalCountries', '2'), ('list', "Hong Kong, People's Republic of China")]
# [('currency', 'http://www.wikidata.org/entity/Q56302633'), ('currencyName', 'Ouguiya (1973-2017)'), ('totalCountries', '2'), ('list', 'Mauritania, Sahrawi Arab Democratic Republic')]
# [('currency', 'http://www.wikidata.org/entity/Q207669'), ('currencyName', 'Hungarian pengő'), ('totalCountries', '2'), ('list', 'Kingdom of Hungary, Republic of Hungary')]
# [('currency', 'http://www.wikidata.org/entity/Q306306'), ('currencyName', 'Austro-Hungarian gulden'), ('totalCountries', '2'), ('list', 'Austria-Hungary, Austrian Empire')]
# [('currency', 'http://www.wikidata.org/entity/Q618653'), ('currencyName', 'North Yemeni rial'), ('totalCountries', '2'), ('list', 'Mutawakkilite Kingdom of Yemen, Yemen Arab Republic')]
# [('currency', 'http://www.wikidata.org/entity/Q56374559'), ('currencyName', 'Manat'), ('totalCountries', '2'), ('list', 'Azerbaijan, Turkmenistan')]
# [('currency', 'http://www.wikidata.org/entity/Q4124886'), ('currencyName', 'Red Army won'), ('totalCountries', '2'), ('list', 'North Korea, Soviet Union')]
# [('currency', 'http://www.wikidata.org/entity/Q5527593'), ('currencyName', 'Gaucho'), ('totalCountries', '2'), ('list', 'Argentina, Brazil')]
# [('currency', 'http://www.wikidata.org/entity/Q737779'), ('currencyName', 'Caribbean guilder'), ('totalCountries', '2'), ('list', 'Curaçao, Sint Maarten')]
# 24

# %%
#adding filtering condition
queryString = """    
    SELECT ?currency ?currencyName (COUNT(DISTINCT ?country) AS ?totalCountries) 
            (GROUP_CONCAT(DISTINCT ?countryName ; separator =", " ) AS ?list)
    WHERE {
       # ?currency wdt:P31 wd:Q8142.
       # ?currency wdt:P17 ?country.
       # ?country wdt:P31* ?class.
       # get the label
       # ?currency sc:name ?currencyName.
       # ?country sc:name ?countryName.
       FILTER( ?class != wd:Q3024240 && NOT EXISTS {?currency wdt:P582 ?enddate} )
    }

GROUP BY ?currency ?currencyName
HAVING ( COUNT(DISTINCT ?country) >= 2)
ORDER BY DESC (?totalCountries)
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('currency', 'http://www.wikidata.org/entity/Q4916'), ('currencyName', 'euro'), ('totalCountries', '23'), ('list', 'Andorra, Austria, Belgium, Cyprus, Estonia, Finland, France, Germany, Greece, Ireland, Italy, Latvia, Lithuania, Luxembourg, Malta, Monaco, Netherlands, Portugal, San Marino, Slovakia, Slovenia, Spain, Vatican City')]
# [('currency', 'http://www.wikidata.org/entity/Q26365'), ('currencyName', 'Eastern Caribbean dollar'), ('totalCountries', '8'), ('list', 'Anguilla, Antigua and Barbuda, Dominica, Grenada, Montserrat, Saint Kitts and Nevis, Saint Lucia, Saint Vincent and the Grenadines')]
# [('currency', 'http://www.wikidata.org/entity/Q861690'), ('currencyName', 'West African CFA franc'), ('totalCountries', '8'), ('list', 'Benin, Burkina Faso, Guinea-Bissau, Ivory Coast, Mali, Niger, Senegal, Togo')]
# [('currency', 'http://www.wikidata.org/entity/Q847739'), ('currencyName', 'Central African CFA franc'), ('totalCountries', '6'), ('list', 'Cameroon, Central African Republic, Chad, Equatorial Guinea, Gabon, Republic of the Congo')]
# [('currency', 'http://www.wikidata.org/entity/Q5639749'), ('currencyName', 'Haitian livre'), ('totalCountries', '4'), ('list', 'First Empire of Haiti, Haiti, Saint-Domingue, State of Haiti')]
# [('currency', 'http://www.wikidata.org/entity/Q804170'), ('currencyName', 'Baiocco'), ('totalCountries', '3'), ('list', 'Papal States, Roman Republic')]
# [('currency', 'http://www.wikidata.org/entity/Q1415602'), ('currencyName', 'Kopeck'), ('totalCountries', '3'), ('list', 'Russia, Soviet Union, Ukraine')]
# [('currency', 'http://www.wikidata.org/entity/Q1983857'), ('currencyName', 'Abkhazian apsar'), ('totalCountries', '2'), ('list', 'Georgia, Republic of Abkhazia')]
# [('currency', 'http://www.wikidata.org/entity/Q19953480'), ('currencyName', 'chuzan-tsuho'), ('totalCountries', '2'), ('list', 'Chūzan, Ryukyu Kingdom')]
# [('currency', 'http://www.wikidata.org/entity/Q25344'), ('currencyName', 'Swiss franc'), ('totalCountries', '2'), ('list', 'Liechtenstein, Switzerland')]
# [('currency', 'http://www.wikidata.org/entity/Q722411'), ('currencyName', 'Hungarian adópengő'), ('totalCountries', '2'), ('list', 'Kingdom of Hungary, Republic of Hungary')]
# [('currency', 'http://www.wikidata.org/entity/Q2348843'), ('currencyName', 'Cambodian tical'), ('totalCountries', '2'), ('list', 'Cambodia, Siam')]
# [('currency', 'http://www.wikidata.org/entity/Q522701'), ('currencyName', 'Netherlands Antillean guilder'), ('totalCountries', '2'), ('list', 'Curaçao, Sint Maarten')]
# [('currency', 'http://www.wikidata.org/entity/Q172872'), ('currencyName', 'Turkish lira'), ('totalCountries', '2'), ('list', 'Turkey, Turkish Republic of Northern Cyprus')]
# [('currency', 'http://www.wikidata.org/entity/Q106615825'), ('currencyName', 'valadia'), ('totalCountries', '2'), ('list', 'Kingdom of Portugal, Marinid Dynasty')]
# [('currency', 'http://www.wikidata.org/entity/Q31015'), ('currencyName', 'Hong Kong dollar'), ('totalCountries', '2'), ('list', "Hong Kong, People's Republic of China")]
# [('currency', 'http://www.wikidata.org/entity/Q56302633'), ('currencyName', 'Ouguiya (1973-2017)'), ('totalCountries', '2'), ('list', 'Mauritania, Sahrawi Arab Democratic Republic')]
# [('currency', 'http://www.wikidata.org/entity/Q207669'), ('currencyName', 'Hungarian pengő'), ('totalCountries', '2'), ('list', 'Kingdom of Hungary, Republic of Hungary')]
# [('currency', 'http://www.wikidata.org/entity/Q306306'), ('currencyName', 'Austro-Hungarian gulden'), ('totalCountries', '2'), ('list', 'Austria-Hungary, Austrian Empire')]
# [('currency', 'http://www.wikidata.org/entity/Q618653'), ('currencyName', 'North Yemeni rial'), ('totalCountries', '2'), ('list', 'Mutawakkilite Kingdom of Yemen, Yemen Arab Republic')]
# [('currency', 'http://www.wikidata.org/entity/Q56374559'), ('currencyName', 'Manat'), ('totalCountries', '2'), ('list', 'Azerbaijan, Turkmenistan')]
# [('currency', 'http://www.wikidata.org/entity/Q4124886'), ('currencyName', 'Red Army won'), ('totalCountries', '2'), ('list', 'North Korea, Soviet Union')]
# [('currency', 'http://www.wikidata.org/entity/Q5527593'), ('currencyName', 'Gaucho'), ('totalCountries', '2'), ('list', 'Argentina, Brazil')]
# [('currency', 'http://www.wikidata.org/entity/Q737779'), ('currencyName', 'Caribbean guilder'), ('totalCountries', '2'), ('list', 'Curaçao, Sint Maarten')]
# 24

# %%
 #Back to 1st version(CANDIDATE FINAL QUERY)
queryString = """    
    SELECT ?currency ?currencyName (COUNT(DISTINCT ?country) AS ?totalCountries) (GROUP_CONCAT(DISTINCT ?countryName ; separator =", " ) AS ?list)
    WHERE {
       # ?country wdt:P31 ?class;
                wdt:P38 ?currency.
       # ?class wdt:P279* wd:Q6256.

       # get the label
       # ?currency sc:name ?currencyName.
       # ?country sc:name ?countryName.
    }

GROUP BY ?currency ?currencyName
HAVING ( COUNT(DISTINCT ?country) >= 2)
ORDER BY DESC (?totalCountries)
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('currency', 'http://www.wikidata.org/entity/Q4916'), ('currencyName', 'euro'), ('totalCountries', '25'), ('list', 'Andorra, Austria, Belgium, Cyprus, Estonia, Finland, France, Germany, Greece, Ireland, Italy, Kingdom of the Netherlands, Latvia, Lithuania, Luxembourg, Malta, Monaco, Montenegro, Netherlands, Portugal, San Marino, Slovakia, Slovenia, Spain, Vatican City')]
# [('currency', 'http://www.wikidata.org/entity/Q4917'), ('currencyName', 'United States dollar'), ('totalCountries', '12'), ('list', 'American Samoa, East Timor, Ecuador, El Salvador, Federated States of Micronesia, Liberia, Marshall Islands, Northern Mariana Islands, Palau, Panama, United States of America, Zimbabwe')]
# [('currency', 'http://www.wikidata.org/entity/Q861690'), ('currencyName', 'West African CFA franc'), ('totalCountries', '8'), ('list', 'Benin, Burkina Faso, Guinea-Bissau, Ivory Coast, Mali, Niger, Senegal, Togo')]
# [('currency', 'http://www.wikidata.org/entity/Q26365'), ('currencyName', 'Eastern Caribbean dollar'), ('totalCountries', '6'), ('list', 'Antigua and Barbuda, Dominica, Grenada, Saint Kitts and Nevis, Saint Lucia, Saint Vincent and the Grenadines')]
# [('currency', 'http://www.wikidata.org/entity/Q847739'), ('currencyName', 'Central African CFA franc'), ('totalCountries', '6'), ('list', 'Cameroon, Central African Republic, Chad, Equatorial Guinea, Gabon, Republic of the Congo')]
# [('currency', 'http://www.wikidata.org/entity/Q259502'), ('currencyName', 'Australian dollar'), ('totalCountries', '4'), ('list', 'Australia, Kiribati, Nauru, Tuvalu')]
# [('currency', 'http://www.wikidata.org/entity/Q199462'), ('currencyName', 'Egyptian pound'), ('totalCountries', '4'), ('list', 'Egypt, Khedivate of Egypt, Kingdom of Egypt, Sultanate of Egypt')]
# [('currency', 'http://www.wikidata.org/entity/Q181907'), ('currencyName', 'South African rand'), ('totalCountries', '3'), ('list', 'Lesotho, Namibia, South Africa')]
# [('currency', 'http://www.wikidata.org/entity/Q1472704'), ('currencyName', 'New Zealand dollar'), ('totalCountries', '3'), ('list', 'Cook Islands, New Zealand, Niue')]
# [('currency', 'http://www.wikidata.org/entity/Q25224'), ('currencyName', 'pound sterling'), ('totalCountries', '3'), ('list', 'British Empire, United Kingdom, Wales')]
# [('currency', 'http://www.wikidata.org/entity/Q25417'), ('currencyName', 'Danish krone'), ('totalCountries', '3'), ('list', 'Danish Realm, Denmark, Greenland')]
# [('currency', 'http://www.wikidata.org/entity/Q199471'), ('currencyName', 'Afghan afghani'), ('totalCountries', '3'), ('list', 'Afghanistan, Islamic Emirate of Afghanistan, Islamic Republic of Afghanistan')]
# [('currency', 'http://www.wikidata.org/entity/Q130498'), ('currencyName', 'Armenian dram'), ('totalCountries', '2'), ('list', 'Armenia, Republic of Artsakh')]
# [('currency', 'http://www.wikidata.org/entity/Q206243'), ('currencyName', 'birr'), ('totalCountries', '2'), ('list', 'Ethiopia, Ethiopian Empire')]
# [('currency', 'http://www.wikidata.org/entity/Q952064'), ('currencyName', 'Roman currency'), ('totalCountries', '2'), ('list', 'Roman Empire, Western Roman Empire (395-476 AD)')]
# [('currency', 'http://www.wikidata.org/entity/Q184172'), ('currencyName', 'French franc'), ('totalCountries', '2'), ('list', 'First French Empire, French colonial empire')]
# [('currency', 'http://www.wikidata.org/entity/Q25344'), ('currencyName', 'Swiss franc'), ('totalCountries', '2'), ('list', 'Liechtenstein, Switzerland')]
# [('currency', 'http://www.wikidata.org/entity/Q191068'), ('currencyName', 'Faroese króna'), ('totalCountries', '2'), ('list', 'Danish Realm, Faroe Islands')]
# [('currency', 'http://www.wikidata.org/entity/Q172872'), ('currencyName', 'Turkish lira'), ('totalCountries', '2'), ('list', 'Turkey, Turkish Republic of Northern Cyprus')]
# [('currency', 'http://www.wikidata.org/entity/Q8146'), ('currencyName', 'Japanese yen'), ('totalCountries', '2'), ('list', 'Empire of Japan, Japan')]
# [('currency', 'http://www.wikidata.org/entity/Q41044'), ('currencyName', 'Russian ruble'), ('totalCountries', '2'), ('list', 'Russia, South Ossetia')]
# [('currency', 'http://www.wikidata.org/entity/Q191830'), ('currencyName', 'dinar'), ('totalCountries', '2'), ('list', 'Fatimid Caliphate, Timurid Empire')]
# [('currency', 'http://www.wikidata.org/entity/Q188608'), ('currencyName', 'Iranian rial'), ('totalCountries', '2'), ('list', 'Iran, Pahlavi Dynasty')]
# 23

# %%
#Back to 1st version adding filter for historical countries
queryString = """    
    SELECT ?currency ?currencyName (COUNT(DISTINCT ?country) AS ?totalCountries) (GROUP_CONCAT(DISTINCT ?countryName ; separator =", " ) AS ?list)
    WHERE {
       # ?country wdt:P31 ?class;
                wdt:P38 ?currency.
       
       # ?class wdt:P279 wd:Q6256.
       
       # ?currency wdt:P31 ?currClass.
       FILTER(?class != wd:Q3024240)
       # get the label
       # ?currency sc:name ?currencyName.
       # ?country sc:name ?countryName.
       
    } 

GROUP BY ?currency ?currencyName
HAVING ( COUNT(DISTINCT ?country) >= 2 )
ORDER BY DESC (?totalCountries)
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('currency', 'http://www.wikidata.org/entity/Q4916'), ('currencyName', 'euro'), ('totalCountries', '24'), ('list', 'Andorra, Austria, Belgium, Cyprus, Estonia, Finland, France, Germany, Greece, Ireland, Italy, Kingdom of the Netherlands, Latvia, Lithuania, Luxembourg, Malta, Monaco, Montenegro, Portugal, San Marino, Slovakia, Slovenia, Spain, Vatican City')]
# [('currency', 'http://www.wikidata.org/entity/Q4917'), ('currencyName', 'United States dollar'), ('totalCountries', '10'), ('list', 'East Timor, Ecuador, El Salvador, Federated States of Micronesia, Liberia, Marshall Islands, Palau, Panama, United States of America, Zimbabwe')]
# [('currency', 'http://www.wikidata.org/entity/Q861690'), ('currencyName', 'West African CFA franc'), ('totalCountries', '8'), ('list', 'Benin, Burkina Faso, Guinea-Bissau, Ivory Coast, Mali, Niger, Senegal, Togo')]
# [('currency', 'http://www.wikidata.org/entity/Q26365'), ('currencyName', 'Eastern Caribbean dollar'), ('totalCountries', '6'), ('list', 'Antigua and Barbuda, Dominica, Grenada, Saint Kitts and Nevis, Saint Lucia, Saint Vincent and the Grenadines')]
# [('currency', 'http://www.wikidata.org/entity/Q847739'), ('currencyName', 'Central African CFA franc'), ('totalCountries', '6'), ('list', 'Cameroon, Central African Republic, Chad, Equatorial Guinea, Gabon, Republic of the Congo')]
# [('currency', 'http://www.wikidata.org/entity/Q259502'), ('currencyName', 'Australian dollar'), ('totalCountries', '4'), ('list', 'Australia, Kiribati, Nauru, Tuvalu')]
# [('currency', 'http://www.wikidata.org/entity/Q199462'), ('currencyName', 'Egyptian pound'), ('totalCountries', '4'), ('list', 'Egypt, Khedivate of Egypt, Kingdom of Egypt, Sultanate of Egypt')]
# [('currency', 'http://www.wikidata.org/entity/Q181907'), ('currencyName', 'South African rand'), ('totalCountries', '3'), ('list', 'Lesotho, Namibia, South Africa')]
# [('currency', 'http://www.wikidata.org/entity/Q1472704'), ('currencyName', 'New Zealand dollar'), ('totalCountries', '3'), ('list', 'Cook Islands, New Zealand, Niue')]
# [('currency', 'http://www.wikidata.org/entity/Q25417'), ('currencyName', 'Danish krone'), ('totalCountries', '3'), ('list', 'Danish Realm, Denmark, Greenland')]
# [('currency', 'http://www.wikidata.org/entity/Q199471'), ('currencyName', 'Afghan afghani'), ('totalCountries', '3'), ('list', 'Afghanistan, Islamic Emirate of Afghanistan, Islamic Republic of Afghanistan')]
# [('currency', 'http://www.wikidata.org/entity/Q25344'), ('currencyName', 'Swiss franc'), ('totalCountries', '2'), ('list', 'Liechtenstein, Switzerland')]
# [('currency', 'http://www.wikidata.org/entity/Q191068'), ('currencyName', 'Faroese króna'), ('totalCountries', '2'), ('list', 'Danish Realm, Faroe Islands')]
# [('currency', 'http://www.wikidata.org/entity/Q172872'), ('currencyName', 'Turkish lira'), ('totalCountries', '2'), ('list', 'Turkey, Turkish Republic of Northern Cyprus')]
# [('currency', 'http://www.wikidata.org/entity/Q41044'), ('currencyName', 'Russian ruble'), ('totalCountries', '2'), ('list', 'Russia, South Ossetia')]
# 15

# %%
#Back to 1st version adding filter (with not exists) for historical countries
queryString = """    
    SELECT ?currency ?currencyName (COUNT(DISTINCT ?country) AS ?totalCountries) (GROUP_CONCAT(DISTINCT ?countryName ; separator =", " ) AS ?list)
    WHERE {
       # ?country wdt:P31 ?class;
                wdt:P38 ?currency.
       
       # ?class wdt:P279 wd:Q6256.
       
       # ?currency wdt:P31 ?currClass.
       FILTER(NOT EXISTS {?country wdt:P31 wd:Q3024240})
       # get the label
       # ?currency sc:name ?currencyName.
       # ?country sc:name ?countryName.
       
    } 

GROUP BY ?currency ?currencyName
HAVING ( COUNT(DISTINCT ?country) >= 2 )
ORDER BY DESC (?totalCountries)
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('currency', 'http://www.wikidata.org/entity/Q4916'), ('currencyName', 'euro'), ('totalCountries', '24'), ('list', 'Andorra, Austria, Belgium, Cyprus, Estonia, Finland, France, Germany, Greece, Ireland, Italy, Kingdom of the Netherlands, Latvia, Lithuania, Luxembourg, Malta, Monaco, Montenegro, Portugal, San Marino, Slovakia, Slovenia, Spain, Vatican City')]
# [('currency', 'http://www.wikidata.org/entity/Q4917'), ('currencyName', 'United States dollar'), ('totalCountries', '10'), ('list', 'East Timor, Ecuador, El Salvador, Federated States of Micronesia, Liberia, Marshall Islands, Palau, Panama, United States of America, Zimbabwe')]
# [('currency', 'http://www.wikidata.org/entity/Q861690'), ('currencyName', 'West African CFA franc'), ('totalCountries', '8'), ('list', 'Benin, Burkina Faso, Guinea-Bissau, Ivory Coast, Mali, Niger, Senegal, Togo')]
# [('currency', 'http://www.wikidata.org/entity/Q26365'), ('currencyName', 'Eastern Caribbean dollar'), ('totalCountries', '6'), ('list', 'Antigua and Barbuda, Dominica, Grenada, Saint Kitts and Nevis, Saint Lucia, Saint Vincent and the Grenadines')]
# [('currency', 'http://www.wikidata.org/entity/Q847739'), ('currencyName', 'Central African CFA franc'), ('totalCountries', '6'), ('list', 'Cameroon, Central African Republic, Chad, Equatorial Guinea, Gabon, Republic of the Congo')]
# [('currency', 'http://www.wikidata.org/entity/Q259502'), ('currencyName', 'Australian dollar'), ('totalCountries', '4'), ('list', 'Australia, Kiribati, Nauru, Tuvalu')]
# [('currency', 'http://www.wikidata.org/entity/Q181907'), ('currencyName', 'South African rand'), ('totalCountries', '3'), ('list', 'Lesotho, Namibia, South Africa')]
# [('currency', 'http://www.wikidata.org/entity/Q1472704'), ('currencyName', 'New Zealand dollar'), ('totalCountries', '3'), ('list', 'Cook Islands, New Zealand, Niue')]
# [('currency', 'http://www.wikidata.org/entity/Q25417'), ('currencyName', 'Danish krone'), ('totalCountries', '3'), ('list', 'Danish Realm, Denmark, Greenland')]
# [('currency', 'http://www.wikidata.org/entity/Q25344'), ('currencyName', 'Swiss franc'), ('totalCountries', '2'), ('list', 'Liechtenstein, Switzerland')]
# [('currency', 'http://www.wikidata.org/entity/Q191068'), ('currencyName', 'Faroese króna'), ('totalCountries', '2'), ('list', 'Danish Realm, Faroe Islands')]
# [('currency', 'http://www.wikidata.org/entity/Q199462'), ('currencyName', 'Egyptian pound'), ('totalCountries', '2'), ('list', 'Egypt, Sultanate of Egypt')]
# [('currency', 'http://www.wikidata.org/entity/Q172872'), ('currencyName', 'Turkish lira'), ('totalCountries', '2'), ('list', 'Turkey, Turkish Republic of Northern Cyprus')]
# [('currency', 'http://www.wikidata.org/entity/Q41044'), ('currencyName', 'Russian ruble'), ('totalCountries', '2'), ('list', 'Russia, South Ossetia')]
# 14

# %%
# return countries which use Egyptian pound
queryString = """
SELECT DISTINCT ?country?name
WHERE {
   # ?country wdt:P31 ?class;
            wdt:P38 wd:Q199462.
   # ?class wdt:P279 wd:Q6256.
   # ?country sc:name ?name.
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('country', 'http://www.wikidata.org/entity/Q127861'), ('name', 'Khedivate of Egypt')]
# [('country', 'http://www.wikidata.org/entity/Q370173'), ('name', 'Sultanate of Egypt')]
# [('country', 'http://www.wikidata.org/entity/Q124943'), ('name', 'Kingdom of Egypt')]
# [('country', 'http://www.wikidata.org/entity/Q79'), ('name', 'Egypt')]
# 4

# %%
#return what Kingdom of Egypt is instance of
queryString = """
SELECT ?o ?name
WHERE {
   wd:Q124943 wdt:P31 ?o.
   # ?o sc:name ?name.
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('o', 'http://www.wikidata.org/entity/Q1323642'), ('name', 'transcontinental country')]
# [('o', 'http://www.wikidata.org/entity/Q3024240'), ('name', 'historical country')]
# [('o', 'http://www.wikidata.org/entity/Q1151405'), ('name', 'client state')]
# 3

# %%
#return what Sultanate of Egypt is instance of
queryString = """
SELECT ?o ?name
WHERE {
   wd:Q370173 wdt:P31 ?o.
   # ?o sc:name ?name.
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('o', 'http://www.wikidata.org/entity/Q1323642'), ('name', 'transcontinental country')]
# [('o', 'http://www.wikidata.org/entity/Q21479969'), ('name', 'British protectorate')]
# [('o', 'http://www.wikidata.org/entity/Q12759805'), ('name', 'sultanate')]
# 3

# %%
#return property and obj for Sultanate of Egypt
queryString = """
SELECT DISTINCT ?p ?pname ?obj ?name 
WHERE {
   wd:Q370173 ?p ?obj .
   # get the label
   # ?obj sc:name ?name.
   # ?p sc:name ?pname.
}
LIMIT 30
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P122'), ('pname', 'basic form of government'), ('obj', 'http://www.wikidata.org/entity/Q41614'), ('name', 'constitutional monarchy')]
# [('p', 'http://www.wikidata.org/prop/direct/P1313'), ('pname', 'office held by head of government'), ('obj', 'http://www.wikidata.org/entity/Q4115925'), ('name', 'Sultan of Egypt')]
# [('p', 'http://www.wikidata.org/prop/direct/P1365'), ('pname', 'replaces'), ('obj', 'http://www.wikidata.org/entity/Q127861'), ('name', 'Khedivate of Egypt')]
# [('p', 'http://www.wikidata.org/prop/direct/P1366'), ('pname', 'replaced by'), ('obj', 'http://www.wikidata.org/entity/Q124943'), ('name', 'Kingdom of Egypt')]
# [('p', 'http://www.wikidata.org/prop/direct/P140'), ('pname', 'religion'), ('obj', 'http://www.wikidata.org/entity/Q483654'), ('name', 'Sunni Islam')]
# [('p', 'http://www.wikidata.org/prop/direct/P155'), ('pname', 'follows'), ('obj', 'http://www.wikidata.org/entity/Q127861'), ('name', 'Khedivate of Egypt')]
# [('p', 'http://www.wikidata.org/prop/direct/P156'), ('pname', 'followed by'), ('obj', 'http://www.wikidata.org/entity/Q124943'), ('name', 'Kingdom of Egypt')]
# [('p', 'http://www.wikidata.org/prop/direct/P17'), ('pname', 'country'), ('obj', 'http://www.wikidata.org/entity/Q79'), ('name', 'Egypt')]
# [('p', 'http://www.wikidata.org/prop/direct/P2936'), ('pname', 'language used'), ('obj', 'http://www.wikidata.org/entity/Q1860'), ('name', 'English')]
# [('p', 'http://www.wikidata.org/prop/direct/P2936'), ('pname', 'language used'), ('obj', 'http://www.wikidata.org/entity/Q13955'), ('name', 'Arabic')]
# [('p', 'http://www.wikidata.org/prop/direct/P30'), ('pname', 'continent'), ('obj', 'http://www.wikidata.org/entity/Q15'), ('name', 'Africa')]
# [('p', 'http://www.wikidata.org/prop/direct/P3075'), ('pname', 'official religion'), ('obj', 'http://www.wikidata.org/entity/Q483654'), ('name', 'Sunni Islam')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pname', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q1323642'), ('name', 'transcontinental country')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pname', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q12759805'), ('name', 'sultanate')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pname', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q21479969'), ('name', 'British protectorate')]
# [('p', 'http://www.wikidata.org/prop/direct/P36'), ('pname', 'capital'), ('obj', 'http://www.wikidata.org/entity/Q85'), ('name', 'Cairo')]
# [('p', 'http://www.wikidata.org/prop/direct/P37'), ('pname', 'official language'), ('obj', 'http://www.wikidata.org/entity/Q13955'), ('name', 'Arabic')]
# [('p', 'http://www.wikidata.org/prop/direct/P37'), ('pname', 'official language'), ('obj', 'http://www.wikidata.org/entity/Q1860'), ('name', 'English')]
# [('p', 'http://www.wikidata.org/prop/direct/P38'), ('pname', 'currency'), ('obj', 'http://www.wikidata.org/entity/Q199462'), ('name', 'Egyptian pound')]
# [('p', 'http://www.wikidata.org/prop/direct/P47'), ('pname', 'shares border with'), ('obj', 'http://www.wikidata.org/entity/Q7075820'), ('name', 'Occupied Enemy Territory Administration')]
# [('p', 'http://www.wikidata.org/prop/direct/P910'), ('pname', "topic's main category"), ('obj', 'http://www.wikidata.org/entity/Q32690880'), ('name', 'Category:Sultanate of Egypt')]
# 21

# %%
# return all properties for Roman currency
queryString = """
SELECT DISTINCT ?p ?name
WHERE {
   # bind something
   wd:Q952064 ?p ?obj .
   # get the label
   # ?p sc:name ?name.
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P1269'), ('name', 'facet of')]
# [('p', 'http://www.wikidata.org/prop/direct/P1296'), ('name', 'Gran Enciclopèdia Catalana ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1343'), ('name', 'described by source')]
# [('p', 'http://www.wikidata.org/prop/direct/P244'), ('name', 'Library of Congress authority ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2581'), ('name', 'BabelNet ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P268'), ('name', 'Bibliothèque nationale de France ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('name', 'instance of')]
# [('p', 'http://www.wikidata.org/prop/direct/P3219'), ('name', 'Encyclopædia Universalis ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3417'), ('name', 'Quora topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P373'), ('name', 'Commons category')]
# [('p', 'http://www.wikidata.org/prop/direct/P4212'), ('name', 'PACTOLS thesaurus ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P508'), ('name', 'BNCF Thesaurus ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('name', 'has part')]
# [('p', 'http://www.wikidata.org/prop/direct/P646'), ('name', 'Freebase ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7818'), ('name', 'French Vikidia ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P910'), ('name', "topic's main category")]
# [('p', 'http://www.wikidata.org/prop/direct/P935'), ('name', 'Commons gallery')]
# [('p', 'http://www.wikidata.org/prop/direct/P950'), ('name', 'Biblioteca Nacional de España ID')]
# 18

# %%
# return what Roman currency is instance of
queryString = """
SELECT DISTINCT ?obj ?name
WHERE {
   # bind something
   wd:Q952064 wdt:P31 ?obj .
   # get the label
   # ?obj sc:name ?name.
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('obj', 'http://www.wikidata.org/entity/Q17524420'), ('name', 'aspect of history')]
# 1

# %%
#return property and obj for Roman currency
queryString = """
SELECT DISTINCT ?p ?pname ?obj ?name 
WHERE {
   wd:Q952064 ?p ?obj .
   # get the label
   # ?obj sc:name ?name.
   # ?p sc:name ?pname.
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P1269'), ('pname', 'facet of'), ('obj', 'http://www.wikidata.org/entity/Q1747689'), ('name', 'Ancient Rome')]
# [('p', 'http://www.wikidata.org/prop/direct/P1269'), ('pname', 'facet of'), ('obj', 'http://www.wikidata.org/entity/Q8142'), ('name', 'currency')]
# [('p', 'http://www.wikidata.org/prop/direct/P1343'), ('pname', 'described by source'), ('obj', 'http://www.wikidata.org/entity/Q602358'), ('name', 'Brockhaus and Efron Encyclopedic Dictionary')]
# [('p', 'http://www.wikidata.org/prop/direct/P1343'), ('pname', 'described by source'), ('obj', 'http://www.wikidata.org/entity/Q1138524'), ('name', 'Paulys Realenzyklopädie der klassischen Altertumswissenschaft')]
# [('p', 'http://www.wikidata.org/prop/direct/P1343'), ('pname', 'described by source'), ('obj', 'http://www.wikidata.org/entity/Q30059240'), ('name', "Real'nyj slovar' klassicheskih drevnostej po Ljubkeru")]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pname', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q17524420'), ('name', 'aspect of history')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pname', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q662137'), ('name', 'Roman Republican currency')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pname', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q638048'), ('name', 'Roman Imperial coinage')]
# [('p', 'http://www.wikidata.org/prop/direct/P910'), ('pname', "topic's main category"), ('obj', 'http://www.wikidata.org/entity/Q8386687'), ('name', 'Category:Coins of ancient Rome')]
# 9

# %%
# return what is linked by currency property to Roman currency 
queryString = """
SELECT DISTINCT ?s ?name
WHERE {
   # ?s wdt:P38 wd:Q952064 .
   # get the label
   # ?s sc:name ?name.
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('s', 'http://www.wikidata.org/entity/Q2277'), ('name', 'Roman Empire')]
# [('s', 'http://www.wikidata.org/entity/Q42834'), ('name', 'Western Roman Empire (395-476 AD)')]
# [('s', 'http://www.wikidata.org/entity/Q17167'), ('name', 'Roman Republic')]
# [('s', 'http://www.wikidata.org/entity/Q1247508'), ('name', 'Domain of Soissons')]
# 4

# %%
#return what roman empire is instance of
queryString = """
SELECT DISTINCT ?obj ?name
WHERE {
   # bind something
   wd:Q2277 wdt:P31* ?obj .
   # get the label
   # ?obj sc:name ?name.
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('obj', 'http://www.wikidata.org/entity/Q11514315'), ('name', 'historical period')]
# [('obj', 'http://www.wikidata.org/entity/Q3024240'), ('name', 'historical country')]
# [('obj', 'http://www.wikidata.org/entity/Q48349'), ('name', 'empire')]
# 3

# %%
#return property and obj for historical country
queryString = """
SELECT DISTINCT ?p ?pname ?obj ?name 
WHERE {
   wd:Q3024240 ?p ?obj .
   # get the label
   # ?obj sc:name ?name.
   # ?p sc:name ?pname.
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P1424'), ('pname', "topic's main template"), ('obj', 'http://www.wikidata.org/entity/Q6036853'), ('name', 'Template:Infobox former country')]
# [('p', 'http://www.wikidata.org/prop/direct/P1687'), ('pname', 'Wikidata property'), ('obj', 'http://www.wikidata.org/entity/P17'), ('name', 'country')]
# [('p', 'http://www.wikidata.org/prop/direct/P1889'), ('pname', 'different from'), ('obj', 'http://www.wikidata.org/entity/Q28864179'), ('name', 'proposed country')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pname', 'properties for this type'), ('obj', 'http://www.wikidata.org/entity/P1366'), ('name', 'replaced by')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pname', 'properties for this type'), ('obj', 'http://www.wikidata.org/entity/P36'), ('name', 'capital')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pname', 'properties for this type'), ('obj', 'http://www.wikidata.org/entity/P576'), ('name', 'dissolved, abolished or demolished date')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pname', 'properties for this type'), ('obj', 'http://www.wikidata.org/entity/P1365'), ('name', 'replaces')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pname', 'properties for this type'), ('obj', 'http://www.wikidata.org/entity/P3842'), ('name', 'located in present-day administrative territorial entity')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pname', 'properties for this type'), ('obj', 'http://www.wikidata.org/entity/P571'), ('name', 'inception')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pname', 'subclass of'), ('obj', 'http://www.wikidata.org/entity/Q96196009'), ('name', 'state (former or current)')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pname', 'subclass of'), ('obj', 'http://www.wikidata.org/entity/Q19953632'), ('name', 'former administrative territorial entity')]
# [('p', 'http://www.wikidata.org/prop/direct/P910'), ('pname', "topic's main category"), ('obj', 'http://www.wikidata.org/entity/Q7238252'), ('name', 'Category:Former countries')]
# [('p', 'http://www.wikidata.org/prop/direct/P8952'), ('pname', 'inappropriate property for this type'), ('obj', 'http://www.wikidata.org/entity/P580'), ('name', 'start time')]
# [('p', 'http://www.wikidata.org/prop/direct/P8952'), ('pname', 'inappropriate property for this type'), ('obj', 'http://www.wikidata.org/entity/P582'), ('name', 'end time')]
# 14

# %%
# return nodes which properties link Germany and countries * operator
queryString = """
SELECT DISTINCT ?p ?name
WHERE {
   wd:Q183 ?p ?o.
   # ?o wdt:P279* wd:Q6256.
   # get the label
   # ?p sc:name ?name.
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('name', 'instance of')]
# 1

# %%
#Back to 1st version adding filter (with not exists) for historical countries and not countries replaced by something
queryString = """    
    SELECT ?currency ?currencyName (COUNT(DISTINCT ?country) AS ?totalCountries) (GROUP_CONCAT(DISTINCT ?countryName ; separator =", " ) AS ?list)
    WHERE {
       # ?country wdt:P31 ?class;
                wdt:P38 ?currency.
       
       # ?class wdt:P279 wd:Q6256.
       
       # ?currency wdt:P31 ?currClass.
       FILTER(NOT EXISTS {?country wdt:P31 wd:Q3024240.} && NOT EXISTS {?country wdt:P1366 ?o.})
                                
       # get the label
       # ?currency sc:name ?currencyName.
       # ?country sc:name ?countryName.
       
    } 

GROUP BY ?currency ?currencyName
HAVING ( COUNT(DISTINCT ?country) >= 2 )
ORDER BY DESC (?totalCountries)
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('currency', 'http://www.wikidata.org/entity/Q4916'), ('currencyName', 'euro'), ('totalCountries', '24'), ('list', 'Andorra, Austria, Belgium, Cyprus, Estonia, Finland, France, Germany, Greece, Ireland, Italy, Kingdom of the Netherlands, Latvia, Lithuania, Luxembourg, Malta, Monaco, Montenegro, Portugal, San Marino, Slovakia, Slovenia, Spain, Vatican City')]
# [('currency', 'http://www.wikidata.org/entity/Q4917'), ('currencyName', 'United States dollar'), ('totalCountries', '10'), ('list', 'East Timor, Ecuador, El Salvador, Federated States of Micronesia, Liberia, Marshall Islands, Palau, Panama, United States of America, Zimbabwe')]
# [('currency', 'http://www.wikidata.org/entity/Q861690'), ('currencyName', 'West African CFA franc'), ('totalCountries', '8'), ('list', 'Benin, Burkina Faso, Guinea-Bissau, Ivory Coast, Mali, Niger, Senegal, Togo')]
# [('currency', 'http://www.wikidata.org/entity/Q26365'), ('currencyName', 'Eastern Caribbean dollar'), ('totalCountries', '6'), ('list', 'Antigua and Barbuda, Dominica, Grenada, Saint Kitts and Nevis, Saint Lucia, Saint Vincent and the Grenadines')]
# [('currency', 'http://www.wikidata.org/entity/Q847739'), ('currencyName', 'Central African CFA franc'), ('totalCountries', '6'), ('list', 'Cameroon, Central African Republic, Chad, Equatorial Guinea, Gabon, Republic of the Congo')]
# [('currency', 'http://www.wikidata.org/entity/Q259502'), ('currencyName', 'Australian dollar'), ('totalCountries', '4'), ('list', 'Australia, Kiribati, Nauru, Tuvalu')]
# [('currency', 'http://www.wikidata.org/entity/Q181907'), ('currencyName', 'South African rand'), ('totalCountries', '3'), ('list', 'Lesotho, Namibia, South Africa')]
# [('currency', 'http://www.wikidata.org/entity/Q1472704'), ('currencyName', 'New Zealand dollar'), ('totalCountries', '3'), ('list', 'Cook Islands, New Zealand, Niue')]
# [('currency', 'http://www.wikidata.org/entity/Q25417'), ('currencyName', 'Danish krone'), ('totalCountries', '3'), ('list', 'Danish Realm, Denmark, Greenland')]
# [('currency', 'http://www.wikidata.org/entity/Q25344'), ('currencyName', 'Swiss franc'), ('totalCountries', '2'), ('list', 'Liechtenstein, Switzerland')]
# [('currency', 'http://www.wikidata.org/entity/Q191068'), ('currencyName', 'Faroese króna'), ('totalCountries', '2'), ('list', 'Danish Realm, Faroe Islands')]
# [('currency', 'http://www.wikidata.org/entity/Q172872'), ('currencyName', 'Turkish lira'), ('totalCountries', '2'), ('list', 'Turkey, Turkish Republic of Northern Cyprus')]
# [('currency', 'http://www.wikidata.org/entity/Q41044'), ('currencyName', 'Russian ruble'), ('totalCountries', '2'), ('list', 'Russia, South Ossetia')]
# 13

# %%
# return countries which use Danish krone
queryString = """
SELECT DISTINCT ?country?name
WHERE {
   # ?country wdt:P31 ?class;
            wdt:P38 wd:Q25417.
   # ?class wdt:P279 wd:Q6256.
   # ?country sc:name ?name.
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('country', 'http://www.wikidata.org/entity/Q223'), ('name', 'Greenland')]
# [('country', 'http://www.wikidata.org/entity/Q756617'), ('name', 'Danish Realm')]
# [('country', 'http://www.wikidata.org/entity/Q35'), ('name', 'Denmark')]
# 3

# %%
# return what Danish realm is instance of
queryString = """
SELECT DISTINCT ?o ?name
WHERE {
   wd:Q756617 wdt:P31 ?o.
   # ?o sc:name ?name.
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('o', 'http://www.wikidata.org/entity/Q179164'), ('name', 'unitary state')]
# [('o', 'http://www.wikidata.org/entity/Q20181813'), ('name', 'colonial power')]
# [('o', 'http://www.wikidata.org/entity/Q3624078'), ('name', 'sovereign state')]
# [('o', 'http://www.wikidata.org/entity/Q41614'), ('name', 'constitutional monarchy')]
# [('o', 'http://www.wikidata.org/entity/Q6256'), ('name', 'country')]
# [('o', 'http://www.wikidata.org/entity/Q417175'), ('name', 'kingdom')]
# 6

# %%
#1st version adding filter (with not exists) for historical countries and not countries replaced by something
#and not instance of kingdom
queryString = """    
    SELECT ?currency ?currencyName (COUNT(DISTINCT ?country) AS ?totalCountries) (GROUP_CONCAT(DISTINCT ?countryName ; separator =", " ) AS ?list)
    WHERE {
       # ?country wdt:P31 ?class;
                wdt:P38 ?currency.
       
       # ?class wdt:P279 wd:Q6256.
       
       # ?currency wdt:P31 wd:Q8142.
       FILTER(NOT EXISTS {?country wdt:P31 wd:Q3024240.} && NOT EXISTS {?country wdt:P1366 ?o.}
                && NOT EXISTS {?country wdt:P31 wd:Q417175.})
                                
       # get the label
       # ?currency sc:name ?currencyName.
       # ?country sc:name ?countryName.
       
    } 

GROUP BY ?currency ?currencyName
HAVING ( COUNT(DISTINCT ?country) >= 2 )
ORDER BY DESC (?totalCountries)
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('currency', 'http://www.wikidata.org/entity/Q4916'), ('currencyName', 'euro'), ('totalCountries', '23'), ('list', 'Andorra, Austria, Belgium, Cyprus, Estonia, Finland, France, Germany, Greece, Ireland, Italy, Latvia, Lithuania, Luxembourg, Malta, Monaco, Montenegro, Portugal, San Marino, Slovakia, Slovenia, Spain, Vatican City')]
# [('currency', 'http://www.wikidata.org/entity/Q4917'), ('currencyName', 'United States dollar'), ('totalCountries', '10'), ('list', 'East Timor, Ecuador, El Salvador, Federated States of Micronesia, Liberia, Marshall Islands, Palau, Panama, United States of America, Zimbabwe')]
# [('currency', 'http://www.wikidata.org/entity/Q861690'), ('currencyName', 'West African CFA franc'), ('totalCountries', '8'), ('list', 'Benin, Burkina Faso, Guinea-Bissau, Ivory Coast, Mali, Niger, Senegal, Togo')]
# [('currency', 'http://www.wikidata.org/entity/Q26365'), ('currencyName', 'Eastern Caribbean dollar'), ('totalCountries', '6'), ('list', 'Antigua and Barbuda, Dominica, Grenada, Saint Kitts and Nevis, Saint Lucia, Saint Vincent and the Grenadines')]
# [('currency', 'http://www.wikidata.org/entity/Q847739'), ('currencyName', 'Central African CFA franc'), ('totalCountries', '6'), ('list', 'Cameroon, Central African Republic, Chad, Equatorial Guinea, Gabon, Republic of the Congo')]
# [('currency', 'http://www.wikidata.org/entity/Q259502'), ('currencyName', 'Australian dollar'), ('totalCountries', '4'), ('list', 'Australia, Kiribati, Nauru, Tuvalu')]
# [('currency', 'http://www.wikidata.org/entity/Q1472704'), ('currencyName', 'New Zealand dollar'), ('totalCountries', '3'), ('list', 'Cook Islands, New Zealand, Niue')]
# [('currency', 'http://www.wikidata.org/entity/Q181907'), ('currencyName', 'South African rand'), ('totalCountries', '2'), ('list', 'Namibia, South Africa')]
# [('currency', 'http://www.wikidata.org/entity/Q25344'), ('currencyName', 'Swiss franc'), ('totalCountries', '2'), ('list', 'Liechtenstein, Switzerland')]
# [('currency', 'http://www.wikidata.org/entity/Q172872'), ('currencyName', 'Turkish lira'), ('totalCountries', '2'), ('list', 'Turkey, Turkish Republic of Northern Cyprus')]
# [('currency', 'http://www.wikidata.org/entity/Q41044'), ('currencyName', 'Russian ruble'), ('totalCountries', '2'), ('list', 'Russia, South Ossetia')]
# [('currency', 'http://www.wikidata.org/entity/Q25417'), ('currencyName', 'Danish krone'), ('totalCountries', '2'), ('list', 'Denmark, Greenland')]
# 12

# %%
# return countries which use Russian ruble
queryString = """
SELECT DISTINCT ?country?name
WHERE {
   # ?country wdt:P31 ?class;
            wdt:P38 wd:Q41044.
   # ?class wdt:P279 wd:Q6256.
   # ?country sc:name ?name.
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('country', 'http://www.wikidata.org/entity/Q159'), ('name', 'Russia')]
# [('country', 'http://www.wikidata.org/entity/Q23427'), ('name', 'South Ossetia')]
# 2

# %%
#return property and obj for South Ossetia
queryString = """
SELECT DISTINCT ?p ?pname ?obj ?name 
WHERE {
   wd:Q23427 ?p ?obj .
   # get the label
   # ?obj sc:name ?name.
   # ?p sc:name ?pname.
}
LIMIT 30
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P1151'), ('pname', "topic's main Wikimedia portal"), ('obj', 'http://www.wikidata.org/entity/Q11148074'), ('name', 'Portal:South Ossetia')]
# [('p', 'http://www.wikidata.org/prop/direct/P122'), ('pname', 'basic form of government'), ('obj', 'http://www.wikidata.org/entity/Q49892'), ('name', 'presidential régime')]
# [('p', 'http://www.wikidata.org/prop/direct/P1313'), ('pname', 'office held by head of government'), ('obj', 'http://www.wikidata.org/entity/Q2332585'), ('name', 'Prime Minister of South Ossetia')]
# [('p', 'http://www.wikidata.org/prop/direct/P1336'), ('pname', 'territory claimed by'), ('obj', 'http://www.wikidata.org/entity/Q230'), ('name', 'Georgia')]
# [('p', 'http://www.wikidata.org/prop/direct/P1465'), ('pname', 'category for people who died here'), ('obj', 'http://www.wikidata.org/entity/Q9828708'), ('name', 'Category:Deaths in South Ossetia')]
# [('p', 'http://www.wikidata.org/prop/direct/P150'), ('pname', 'contains administrative territorial entity'), ('obj', 'http://www.wikidata.org/entity/Q12870952'), ('name', 'Tskhinvali District')]
# [('p', 'http://www.wikidata.org/prop/direct/P150'), ('pname', 'contains administrative territorial entity'), ('obj', 'http://www.wikidata.org/entity/Q79863'), ('name', 'Tskhinvali')]
# [('p', 'http://www.wikidata.org/prop/direct/P150'), ('pname', 'contains administrative territorial entity'), ('obj', 'http://www.wikidata.org/entity/Q1472064'), ('name', 'Leningor District')]
# [('p', 'http://www.wikidata.org/prop/direct/P150'), ('pname', 'contains administrative territorial entity'), ('obj', 'http://www.wikidata.org/entity/Q2995277'), ('name', 'Dzau District')]
# [('p', 'http://www.wikidata.org/prop/direct/P150'), ('pname', 'contains administrative territorial entity'), ('obj', 'http://www.wikidata.org/entity/Q1815665'), ('name', 'Znaur District')]
# [('p', 'http://www.wikidata.org/prop/direct/P163'), ('pname', 'flag'), ('obj', 'http://www.wikidata.org/entity/Q209060'), ('name', 'flag of Ossetia')]
# [('p', 'http://www.wikidata.org/prop/direct/P17'), ('pname', 'country'), ('obj', 'http://www.wikidata.org/entity/Q230'), ('name', 'Georgia')]
# [('p', 'http://www.wikidata.org/prop/direct/P17'), ('pname', 'country'), ('obj', 'http://www.wikidata.org/entity/Q23427'), ('name', 'South Ossetia')]
# [('p', 'http://www.wikidata.org/prop/direct/P1792'), ('pname', 'category of associated people'), ('obj', 'http://www.wikidata.org/entity/Q7934311'), ('name', 'Category:South Ossetian people')]
# [('p', 'http://www.wikidata.org/prop/direct/P1830'), ('pname', 'owner of'), ('obj', 'http://www.wikidata.org/entity/Q4506246'), ('name', 'Tskhinvali railway station')]
# [('p', 'http://www.wikidata.org/prop/direct/P1889'), ('pname', 'different from'), ('obj', 'http://www.wikidata.org/entity/Q5237'), ('name', 'Republic of North Ossetia-Alania')]
# [('p', 'http://www.wikidata.org/prop/direct/P194'), ('pname', 'legislative body'), ('obj', 'http://www.wikidata.org/entity/Q2063555'), ('name', 'Parliament of South Ossetia')]
# [('p', 'http://www.wikidata.org/prop/direct/P237'), ('pname', 'coat of arms'), ('obj', 'http://www.wikidata.org/entity/Q476981'), ('name', 'Coat of arms of South Ossetia')]
# [('p', 'http://www.wikidata.org/prop/direct/P2633'), ('pname', 'geography of topic'), ('obj', 'http://www.wikidata.org/entity/Q4135645'), ('name', 'geography of South Ossetia')]
# [('p', 'http://www.wikidata.org/prop/direct/P30'), ('pname', 'continent'), ('obj', 'http://www.wikidata.org/entity/Q48'), ('name', 'Asia')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pname', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q15239622'), ('name', 'disputed territory')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pname', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q123480'), ('name', 'landlocked country')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pname', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q15634554'), ('name', 'state with limited recognition')]
# [('p', 'http://www.wikidata.org/prop/direct/P36'), ('pname', 'capital'), ('obj', 'http://www.wikidata.org/entity/Q79863'), ('name', 'Tskhinvali')]
# [('p', 'http://www.wikidata.org/prop/direct/P37'), ('pname', 'official language'), ('obj', 'http://www.wikidata.org/entity/Q7737'), ('name', 'Russian')]
# [('p', 'http://www.wikidata.org/prop/direct/P37'), ('pname', 'official language'), ('obj', 'http://www.wikidata.org/entity/Q8108'), ('name', 'Georgian')]
# [('p', 'http://www.wikidata.org/prop/direct/P37'), ('pname', 'official language'), ('obj', 'http://www.wikidata.org/entity/Q33968'), ('name', 'Ossetian')]
# [('p', 'http://www.wikidata.org/prop/direct/P38'), ('pname', 'currency'), ('obj', 'http://www.wikidata.org/entity/Q41044'), ('name', 'Russian ruble')]
# [('p', 'http://www.wikidata.org/prop/direct/P421'), ('pname', 'located in time zone'), ('obj', 'http://www.wikidata.org/entity/Q6760'), ('name', 'UTC+03:00')]
# [('p', 'http://www.wikidata.org/prop/direct/P463'), ('pname', 'member of'), ('obj', 'http://www.wikidata.org/entity/Q1500985'), ('name', 'Community for Democracy and Rights of Nations')]
# 30

# %%
#1st version adding filter (with not exists) for historical countries and not countries replaced by something
#and not instance of kingdom and moved subclass of country match on filter
queryString = """    
    SELECT ?currency ?currencyName (COUNT(DISTINCT ?country) AS ?totalCountries) (GROUP_CONCAT(DISTINCT ?countryName ; separator =", " ) AS ?list)
    WHERE {
       # ?country wdt:P31 ?class;
                wdt:P38 ?currency.
       
       # ?currency wdt:P31 wd:Q8142.
       FILTER(NOT EXISTS {?country wdt:P31 wd:Q3024240.} && NOT EXISTS {?country wdt:P1366 ?o.}
                && NOT EXISTS {?country wdt:P31 wd:Q417175.} && EXISTS{?class wdt:P279* wd:Q6256.})
                                
       # get the label
       # ?currency sc:name ?currencyName.
       # ?country sc:name ?countryName.
       
    } 

GROUP BY ?currency ?currencyName
HAVING ( COUNT(DISTINCT ?country) >= 2 )
ORDER BY DESC (?totalCountries)
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('currency', 'http://www.wikidata.org/entity/Q4916'), ('currencyName', 'euro'), ('totalCountries', '24'), ('list', 'Andorra, Austria, Belgium, Cyprus, Estonia, Finland, France, Germany, Greece, Ireland, Italy, Latvia, Lithuania, Luxembourg, Malta, Monaco, Montenegro, Netherlands, Portugal, San Marino, Slovakia, Slovenia, Spain, Vatican City')]
# [('currency', 'http://www.wikidata.org/entity/Q4917'), ('currencyName', 'United States dollar'), ('totalCountries', '12'), ('list', 'American Samoa, East Timor, Ecuador, El Salvador, Federated States of Micronesia, Liberia, Marshall Islands, Northern Mariana Islands, Palau, Panama, United States of America, Zimbabwe')]
# [('currency', 'http://www.wikidata.org/entity/Q861690'), ('currencyName', 'West African CFA franc'), ('totalCountries', '8'), ('list', 'Benin, Burkina Faso, Guinea-Bissau, Ivory Coast, Mali, Niger, Senegal, Togo')]
# [('currency', 'http://www.wikidata.org/entity/Q26365'), ('currencyName', 'Eastern Caribbean dollar'), ('totalCountries', '6'), ('list', 'Antigua and Barbuda, Dominica, Grenada, Saint Kitts and Nevis, Saint Lucia, Saint Vincent and the Grenadines')]
# [('currency', 'http://www.wikidata.org/entity/Q847739'), ('currencyName', 'Central African CFA franc'), ('totalCountries', '6'), ('list', 'Cameroon, Central African Republic, Chad, Equatorial Guinea, Gabon, Republic of the Congo')]
# [('currency', 'http://www.wikidata.org/entity/Q259502'), ('currencyName', 'Australian dollar'), ('totalCountries', '4'), ('list', 'Australia, Kiribati, Nauru, Tuvalu')]
# [('currency', 'http://www.wikidata.org/entity/Q1472704'), ('currencyName', 'New Zealand dollar'), ('totalCountries', '3'), ('list', 'Cook Islands, New Zealand, Niue')]
# [('currency', 'http://www.wikidata.org/entity/Q130498'), ('currencyName', 'Armenian dram'), ('totalCountries', '2'), ('list', 'Armenia, Republic of Artsakh')]
# [('currency', 'http://www.wikidata.org/entity/Q181907'), ('currencyName', 'South African rand'), ('totalCountries', '2'), ('list', 'Namibia, South Africa')]
# [('currency', 'http://www.wikidata.org/entity/Q25344'), ('currencyName', 'Swiss franc'), ('totalCountries', '2'), ('list', 'Liechtenstein, Switzerland')]
# [('currency', 'http://www.wikidata.org/entity/Q172872'), ('currencyName', 'Turkish lira'), ('totalCountries', '2'), ('list', 'Turkey, Turkish Republic of Northern Cyprus')]
# [('currency', 'http://www.wikidata.org/entity/Q25224'), ('currencyName', 'pound sterling'), ('totalCountries', '2'), ('list', 'United Kingdom, Wales')]
# [('currency', 'http://www.wikidata.org/entity/Q41044'), ('currencyName', 'Russian ruble'), ('totalCountries', '2'), ('list', 'Russia, South Ossetia')]
# [('currency', 'http://www.wikidata.org/entity/Q25417'), ('currencyName', 'Danish krone'), ('totalCountries', '2'), ('list', 'Denmark, Greenland')]
# 14

# %%
#Return the currencies used in at least 2 different countries (return also the number of countries using each currency).
# write your final query
queryString = """    
SELECT ?currency ?currencyName (COUNT(DISTINCT ?country) AS ?totalCountries)
    WHERE {
       # ?country wdt:P31 ?class;
                wdt:P38 ?currency.
       
       # ?currency wdt:P31 wd:Q8142.
       FILTER(NOT EXISTS {?country wdt:P31 wd:Q3024240.} && NOT EXISTS {?country wdt:P1366 ?o.}
                && NOT EXISTS {?country wdt:P31 wd:Q417175.} && EXISTS{?class wdt:P279* wd:Q6256.})
                                
       # get the label
       # ?currency sc:name ?currencyName.
       # ?country sc:name ?countryName.
    } 

GROUP BY ?currency ?currencyName
HAVING ( COUNT(DISTINCT ?country) >= 2 )
ORDER BY DESC (?totalCountries)
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('currency', 'http://www.wikidata.org/entity/Q4916'), ('currencyName', 'euro'), ('totalCountries', '24')]
# [('currency', 'http://www.wikidata.org/entity/Q4917'), ('currencyName', 'United States dollar'), ('totalCountries', '12')]
# [('currency', 'http://www.wikidata.org/entity/Q861690'), ('currencyName', 'West African CFA franc'), ('totalCountries', '8')]
# [('currency', 'http://www.wikidata.org/entity/Q26365'), ('currencyName', 'Eastern Caribbean dollar'), ('totalCountries', '6')]
# [('currency', 'http://www.wikidata.org/entity/Q847739'), ('currencyName', 'Central African CFA franc'), ('totalCountries', '6')]
# [('currency', 'http://www.wikidata.org/entity/Q259502'), ('currencyName', 'Australian dollar'), ('totalCountries', '4')]
# [('currency', 'http://www.wikidata.org/entity/Q1472704'), ('currencyName', 'New Zealand dollar'), ('totalCountries', '3')]
# [('currency', 'http://www.wikidata.org/entity/Q130498'), ('currencyName', 'Armenian dram'), ('totalCountries', '2')]
# [('currency', 'http://www.wikidata.org/entity/Q181907'), ('currencyName', 'South African rand'), ('totalCountries', '2')]
# [('currency', 'http://www.wikidata.org/entity/Q25344'), ('currencyName', 'Swiss franc'), ('totalCountries', '2')]
# [('currency', 'http://www.wikidata.org/entity/Q172872'), ('currencyName', 'Turkish lira'), ('totalCountries', '2')]
# [('currency', 'http://www.wikidata.org/entity/Q25224'), ('currencyName', 'pound sterling'), ('totalCountries', '2')]
# [('currency', 'http://www.wikidata.org/entity/Q41044'), ('currencyName', 'Russian ruble'), ('totalCountries', '2')]
# [('currency', 'http://www.wikidata.org/entity/Q25417'), ('currencyName', 'Danish krone'), ('totalCountries', '2')]
# 14

# %% [markdown]
# Final query for this task

# %%
#Return the currencies used in at least 2 different countries (return also the number of countries using each currency).
# write your final query
queryString = """    
SELECT ?currency ?currencyName (COUNT(DISTINCT ?country) AS ?totalCountries)
    WHERE {
       # ?country wdt:P31/wdt:P279* wd:Q6256;
                wdt:P38 ?currency.
       # ?currency wdt:P31 wd:Q8142.
       FILTER(NOT EXISTS {?country wdt:P31 wd:Q3024240.} && NOT EXISTS {?country wdt:P1366 ?o.}
                && NOT EXISTS {?country wdt:P31 wd:Q417175.})
                                
       # get the label
       # ?currency sc:name ?currencyName.
       # ?country sc:name ?countryName.
    } 

GROUP BY ?currency ?currencyName
HAVING ( COUNT(DISTINCT ?country) >= 2 )
ORDER BY DESC (?totalCountries)
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('currency', 'http://www.wikidata.org/entity/Q4916'), ('currencyName', 'euro'), ('totalCountries', '24')]
# [('currency', 'http://www.wikidata.org/entity/Q4917'), ('currencyName', 'United States dollar'), ('totalCountries', '12')]
# [('currency', 'http://www.wikidata.org/entity/Q861690'), ('currencyName', 'West African CFA franc'), ('totalCountries', '8')]
# [('currency', 'http://www.wikidata.org/entity/Q26365'), ('currencyName', 'Eastern Caribbean dollar'), ('totalCountries', '6')]
# [('currency', 'http://www.wikidata.org/entity/Q847739'), ('currencyName', 'Central African CFA franc'), ('totalCountries', '6')]
# [('currency', 'http://www.wikidata.org/entity/Q259502'), ('currencyName', 'Australian dollar'), ('totalCountries', '4')]
# [('currency', 'http://www.wikidata.org/entity/Q1472704'), ('currencyName', 'New Zealand dollar'), ('totalCountries', '3')]
# [('currency', 'http://www.wikidata.org/entity/Q130498'), ('currencyName', 'Armenian dram'), ('totalCountries', '2')]
# [('currency', 'http://www.wikidata.org/entity/Q181907'), ('currencyName', 'South African rand'), ('totalCountries', '2')]
# [('currency', 'http://www.wikidata.org/entity/Q25344'), ('currencyName', 'Swiss franc'), ('totalCountries', '2')]
# [('currency', 'http://www.wikidata.org/entity/Q172872'), ('currencyName', 'Turkish lira'), ('totalCountries', '2')]
# [('currency', 'http://www.wikidata.org/entity/Q25224'), ('currencyName', 'pound sterling'), ('totalCountries', '2')]
# [('currency', 'http://www.wikidata.org/entity/Q41044'), ('currencyName', 'Russian ruble'), ('totalCountries', '2')]
# [('currency', 'http://www.wikidata.org/entity/Q25417'), ('currencyName', 'Danish krone'), ('totalCountries', '2')]
# 14

# %% [markdown]
# ## Task 7
# Consider the currencies obtained in task 6, for each currency return the number of people using that currency (hint: consider the maximum popolation available for each country).

# %%
# return all properties for Italy
queryString = """
SELECT DISTINCT ?p ?name
WHERE {
   # bind something
   wd:Q38 ?p ?obj .
   # get the label
   # ?p sc:name ?name.
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P1005'), ('name', 'Portuguese National Library ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1036'), ('name', 'Dewey Decimal Classification')]
# [('p', 'http://www.wikidata.org/prop/direct/P1081'), ('name', 'Human Development Index')]
# [('p', 'http://www.wikidata.org/prop/direct/P1082'), ('name', 'population')]
# [('p', 'http://www.wikidata.org/prop/direct/P1120'), ('name', 'number of deaths')]
# [('p', 'http://www.wikidata.org/prop/direct/P1151'), ('name', "topic's main Wikimedia portal")]
# [('p', 'http://www.wikidata.org/prop/direct/P1198'), ('name', 'unemployment rate')]
# [('p', 'http://www.wikidata.org/prop/direct/P122'), ('name', 'basic form of government')]
# [('p', 'http://www.wikidata.org/prop/direct/P1225'), ('name', 'U.S. National Archives Identifier')]
# [('p', 'http://www.wikidata.org/prop/direct/P1245'), ('name', 'OmegaWiki Defined Meaning')]
# [('p', 'http://www.wikidata.org/prop/direct/P1296'), ('name', 'Gran Enciclopèdia Catalana ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1313'), ('name', 'office held by head of government')]
# [('p', 'http://www.wikidata.org/prop/direct/P1343'), ('name', 'described by source')]
# [('p', 'http://www.wikidata.org/prop/direct/P1365'), ('name', 'replaces')]
# [('p', 'http://www.wikidata.org/prop/direct/P1417'), ('name', 'Encyclopædia Britannica Online ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1419'), ('name', 'shape')]
# [('p', 'http://www.wikidata.org/prop/direct/P1438'), ('name', 'Jewish Encyclopedia ID (Russian)')]
# [('p', 'http://www.wikidata.org/prop/direct/P1451'), ('name', 'motto text')]
# [('p', 'http://www.wikidata.org/prop/direct/P1464'), ('name', 'category for people born here')]
# [('p', 'http://www.wikidata.org/prop/direct/P1465'), ('name', 'category for people who died here')]
# [('p', 'http://www.wikidata.org/prop/direct/P150'), ('name', 'contains administrative territorial entity')]
# [('p', 'http://www.wikidata.org/prop/direct/P1549'), ('name', 'demonym')]
# [('p', 'http://www.wikidata.org/prop/direct/P155'), ('name', 'follows')]
# [('p', 'http://www.wikidata.org/prop/direct/P1552'), ('name', 'has quality')]
# [('p', 'http://www.wikidata.org/prop/direct/P1566'), ('name', 'GeoNames ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1589'), ('name', 'lowest point')]
# [('p', 'http://www.wikidata.org/prop/direct/P1617'), ('name', 'BBC Things ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1622'), ('name', 'driving side')]
# [('p', 'http://www.wikidata.org/prop/direct/P163'), ('name', 'flag')]
# [('p', 'http://www.wikidata.org/prop/direct/P1667'), ('name', 'Getty Thesaurus of Geographic Names ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P17'), ('name', 'country')]
# [('p', 'http://www.wikidata.org/prop/direct/P1740'), ('name', 'category for films shot at this location')]
# [('p', 'http://www.wikidata.org/prop/direct/P1791'), ('name', 'category of people buried here')]
# [('p', 'http://www.wikidata.org/prop/direct/P1792'), ('name', 'category of associated people')]
# [('p', 'http://www.wikidata.org/prop/direct/P1842'), ('name', 'Global Anabaptist Mennonite Encyclopedia Online ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1906'), ('name', 'office held by head of state')]
# [('p', 'http://www.wikidata.org/prop/direct/P194'), ('name', 'legislative body')]
# [('p', 'http://www.wikidata.org/prop/direct/P2004'), ('name', 'NALT ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2046'), ('name', 'area')]
# [('p', 'http://www.wikidata.org/prop/direct/P206'), ('name', 'located in or next to body of water')]
# [('p', 'http://www.wikidata.org/prop/direct/P208'), ('name', 'executive body')]
# [('p', 'http://www.wikidata.org/prop/direct/P209'), ('name', 'highest judicial authority')]
# [('p', 'http://www.wikidata.org/prop/direct/P213'), ('name', 'ISNI')]
# [('p', 'http://www.wikidata.org/prop/direct/P214'), ('name', 'VIAF ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2163'), ('name', 'FAST ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2184'), ('name', 'history of topic')]
# [('p', 'http://www.wikidata.org/prop/direct/P2250'), ('name', 'life expectancy')]
# [('p', 'http://www.wikidata.org/prop/direct/P2258'), ('name', 'mobile country code')]
# [('p', 'http://www.wikidata.org/prop/direct/P227'), ('name', 'GND ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2347'), ('name', 'YSO ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P237'), ('name', 'coat of arms')]
# [('p', 'http://www.wikidata.org/prop/direct/P242'), ('name', 'locator map image')]
# [('p', 'http://www.wikidata.org/prop/direct/P244'), ('name', 'Library of Congress authority ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2573'), ('name', 'number of out-of-school children')]
# [('p', 'http://www.wikidata.org/prop/direct/P2581'), ('name', 'BabelNet ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2596'), ('name', 'culture')]
# [('p', 'http://www.wikidata.org/prop/direct/P2633'), ('name', 'geography of topic')]
# [('p', 'http://www.wikidata.org/prop/direct/P2852'), ('name', 'emergency telephone number')]
# [('p', 'http://www.wikidata.org/prop/direct/P2853'), ('name', 'electrical plug type')]
# [('p', 'http://www.wikidata.org/prop/direct/P2855'), ('name', 'VAT-rate')]
# [('p', 'http://www.wikidata.org/prop/direct/P2884'), ('name', 'mains voltage')]
# [('p', 'http://www.wikidata.org/prop/direct/P2924'), ('name', 'Great Russian Encyclopedia Online ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2936'), ('name', 'language used')]
# [('p', 'http://www.wikidata.org/prop/direct/P2950'), ('name', 'Nomisma ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2959'), ('name', 'permanent duplicated item')]
# [('p', 'http://www.wikidata.org/prop/direct/P297'), ('name', 'ISO 3166-1 alpha-2 code')]
# [('p', 'http://www.wikidata.org/prop/direct/P2979'), ('name', 'maritime identification digits')]
# [('p', 'http://www.wikidata.org/prop/direct/P298'), ('name', 'ISO 3166-1 alpha-3 code')]
# [('p', 'http://www.wikidata.org/prop/direct/P2981'), ('name', 'UIC alphabetical country code')]
# [('p', 'http://www.wikidata.org/prop/direct/P2982'), ('name', 'UIC numerical country code')]
# [('p', 'http://www.wikidata.org/prop/direct/P299'), ('name', 'ISO 3166-1 numeric code')]
# [('p', 'http://www.wikidata.org/prop/direct/P2997'), ('name', 'age of majority')]
# [('p', 'http://www.wikidata.org/prop/direct/P30'), ('name', 'continent')]
# [('p', 'http://www.wikidata.org/prop/direct/P3000'), ('name', 'marriageable age')]
# [('p', 'http://www.wikidata.org/prop/direct/P3024'), ('name', 'ITU letter code')]
# [('p', 'http://www.wikidata.org/prop/direct/P3067'), ('name', 'GS1 country code')]
# [('p', 'http://www.wikidata.org/prop/direct/P3068'), ('name', 'WIPO ST.3')]
# [('p', 'http://www.wikidata.org/prop/direct/P3097'), ('name', 'ISBN identifier group')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('name', 'instance of')]
# [('p', 'http://www.wikidata.org/prop/direct/P3106'), ('name', 'Guardian topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3175'), ('name', 'Statoids ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3219'), ('name', 'Encyclopædia Universalis ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3221'), ('name', 'New York Times topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3222'), ('name', 'NE.se ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3270'), ('name', 'compulsory education (minimum age)')]
# [('p', 'http://www.wikidata.org/prop/direct/P3271'), ('name', 'compulsory education (maximum age)')]
# [('p', 'http://www.wikidata.org/prop/direct/P3365'), ('name', 'Treccani ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3417'), ('name', 'Quora topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3422'), ('name', 'INSEE countries and foreign territories code')]
# [('p', 'http://www.wikidata.org/prop/direct/P3479'), ('name', 'Omni topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P349'), ('name', 'National Diet Library ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P35'), ('name', 'head of state')]
# [('p', 'http://www.wikidata.org/prop/direct/P3509'), ('name', 'Dagens Nyheter topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3529'), ('name', 'median income')]
# [('p', 'http://www.wikidata.org/prop/direct/P3553'), ('name', 'Zhihu topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P36'), ('name', 'capital')]
# [('p', 'http://www.wikidata.org/prop/direct/P361'), ('name', 'part of')]
# [('p', 'http://www.wikidata.org/prop/direct/P3612'), ('name', 'Le Monde diplomatique subject ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P37'), ('name', 'official language')]
# [('p', 'http://www.wikidata.org/prop/direct/P373'), ('name', 'Commons category')]
# 100

# %%
# return what Italy is instance of
queryString = """
SELECT DISTINCT ?obj ?name
WHERE {
   wd:Q38 wdt:P31 ?obj .
   
   # ?obj sc:name ?name.
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('obj', 'http://www.wikidata.org/entity/Q3624078'), ('name', 'sovereign state')]
# [('obj', 'http://www.wikidata.org/entity/Q6256'), ('name', 'country')]
# 2

# %%
# return Italy's population
queryString = """
SELECT DISTINCT ?obj ?name
WHERE {
   wd:Q38 wdt:P1082 ?obj .
   
   # ?obj sc:name ?name.
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# Empty

# %%
# return Italy's population
queryString = """
SELECT DISTINCT ?obj 
WHERE {
   wd:Q38 wdt:P1082 ?obj .
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('obj', '60317000')]
# 1

# %%
# return all properties for Euro
queryString = """
SELECT DISTINCT ?p ?name
WHERE {
   wd:Q4916 ?p ?obj .
   # get the label
   # ?p sc:name ?name.
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P1001'), ('name', 'applies to jurisdiction')]
# [('p', 'http://www.wikidata.org/prop/direct/P1245'), ('name', 'OmegaWiki Defined Meaning')]
# [('p', 'http://www.wikidata.org/prop/direct/P1282'), ('name', 'OpenStreetMap tag or key')]
# [('p', 'http://www.wikidata.org/prop/direct/P1365'), ('name', 'replaces')]
# [('p', 'http://www.wikidata.org/prop/direct/P138'), ('name', 'named after')]
# [('p', 'http://www.wikidata.org/prop/direct/P1417'), ('name', 'Encyclopædia Britannica Online ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1482'), ('name', 'Stack Exchange tag')]
# [('p', 'http://www.wikidata.org/prop/direct/P154'), ('name', 'logo image')]
# [('p', 'http://www.wikidata.org/prop/direct/P166'), ('name', 'award received')]
# [('p', 'http://www.wikidata.org/prop/direct/P17'), ('name', 'country')]
# [('p', 'http://www.wikidata.org/prop/direct/P18'), ('name', 'image')]
# [('p', 'http://www.wikidata.org/prop/direct/P1813'), ('name', 'short name')]
# [('p', 'http://www.wikidata.org/prop/direct/P1889'), ('name', 'different from')]
# [('p', 'http://www.wikidata.org/prop/direct/P1993'), ('name', 'TeX string')]
# [('p', 'http://www.wikidata.org/prop/direct/P227'), ('name', 'GND ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2284'), ('name', 'price')]
# [('p', 'http://www.wikidata.org/prop/direct/P2347'), ('name', 'YSO ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P244'), ('name', 'Library of Congress authority ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2442'), ('name', 'conversion to standard unit')]
# [('p', 'http://www.wikidata.org/prop/direct/P268'), ('name', 'Bibliothèque nationale de France ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('name', 'subclass of')]
# [('p', 'http://www.wikidata.org/prop/direct/P2888'), ('name', 'exact match')]
# [('p', 'http://www.wikidata.org/prop/direct/P2924'), ('name', 'Great Russian Encyclopedia Online ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2959'), ('name', 'permanent duplicated item')]
# [('p', 'http://www.wikidata.org/prop/direct/P2968'), ('name', 'QUDT unit ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('name', 'instance of')]
# [('p', 'http://www.wikidata.org/prop/direct/P3219'), ('name', 'Encyclopædia Universalis ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3347'), ('name', 'PermID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3417'), ('name', 'Quora topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P349'), ('name', 'National Diet Library ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3553'), ('name', 'Zhihu topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3569'), ('name', 'Cultureel Woordenboek ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P373'), ('name', 'Commons category')]
# [('p', 'http://www.wikidata.org/prop/direct/P3911'), ('name', 'STW Thesaurus for Economics ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P4527'), ('name', 'UK Parliament thesaurus ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P487'), ('name', 'Unicode character')]
# [('p', 'http://www.wikidata.org/prop/direct/P489'), ('name', 'currency symbol description')]
# [('p', 'http://www.wikidata.org/prop/direct/P498'), ('name', 'ISO 4217 code')]
# [('p', 'http://www.wikidata.org/prop/direct/P5008'), ('name', 'on focus list of Wikimedia project')]
# [('p', 'http://www.wikidata.org/prop/direct/P5019'), ('name', 'Brockhaus Enzyklopädie online ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P508'), ('name', 'BNCF Thesaurus ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5437'), ('name', 'EuroVoc ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P562'), ('name', 'central bank/issuer')]
# [('p', 'http://www.wikidata.org/prop/direct/P580'), ('name', 'start time')]
# [('p', 'http://www.wikidata.org/prop/direct/P6058'), ('name', 'Larousse ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6404'), ('name', "Treccani's Dizionario di Storia ID")]
# [('p', 'http://www.wikidata.org/prop/direct/P646'), ('name', 'Freebase ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6573'), ('name', 'Klexikon article ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7007'), ('name', 'Wolfram Language unit code')]
# [('p', 'http://www.wikidata.org/prop/direct/P7033'), ('name', 'Australian Educational Vocabulary ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7749'), ('name', 'Nomenclature for Museum Cataloging')]
# [('p', 'http://www.wikidata.org/prop/direct/P7818'), ('name', 'French Vikidia ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7822'), ('name', 'Italian Vikidia ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7827'), ('name', 'Spanish Vikidia ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7829'), ('name', 'English Vikidia ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7982'), ('name', 'Hrvatska enciklopedija ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7996'), ('name', 'EH.Net Encyclopedia of Economic and Business History ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8769'), ('name', 'Ontology of units of Measure 2.0 unit ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P902'), ('name', 'HDS ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P910'), ('name', "topic's main category")]
# [('p', 'http://www.wikidata.org/prop/direct/P9318'), ('name', 'Ávvir topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P935'), ('name', 'Commons gallery')]
# [('p', 'http://www.wikidata.org/prop/direct/P9545'), ('name', 'Encyclopedia of China Online Database ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P998'), ('name', 'Curlie ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3328'), ('name', 'wurvoc.org measure ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P9059'), ('name', 'subdivision of this unit')]
# 66

# %%
#final query try
queryString = """
SELECT ?curr ?name (SUM(?people) AS ?totalPopulation) WHERE {
    # ?curr wdt:P17 ?country.
    # ?country wdt:P31 wd:Q6256.
    # ?country wdt:P1082 ?people.
    {
    SELECT ?curr ?name (COUNT(?country) AS ?totCountries)
    WHERE {
       # ?country wdt:P31 wd:Q6256;
                wdt:P38 ?curr.

       # get the label
       # ?curr sc:name ?name.
    }
    GROUP BY ?curr ?name 
    HAVING (COUNT(?country) >= 2)
    }
}
GROUP BY ?curr ?name 
ORDER BY DESC (?totalPopulation)
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('curr', 'http://www.wikidata.org/entity/Q4917'), ('name', 'United States dollar'), ('totalPopulation', '331449281')]
# [('curr', 'http://www.wikidata.org/entity/Q4916'), ('name', 'euro'), ('totalPopulation', '193833944')]
# [('curr', 'http://www.wikidata.org/entity/Q861690'), ('name', 'West African CFA franc'), ('totalPopulation', '121487314')]
# [('curr', 'http://www.wikidata.org/entity/Q188608'), ('name', 'Iranian rial'), ('totalPopulation', '79966230')]
# [('curr', 'http://www.wikidata.org/entity/Q25224'), ('name', 'pound sterling'), ('totalPopulation', '66022273')]
# [('curr', 'http://www.wikidata.org/entity/Q181907'), ('name', 'South African rand'), ('totalPopulation', '59622350')]
# [('curr', 'http://www.wikidata.org/entity/Q847739'), ('name', 'Central African CFA franc'), ('totalPopulation', '49451308')]
# [('curr', 'http://www.wikidata.org/entity/Q259502'), ('name', 'Australian dollar'), ('totalPopulation', '24511800')]
# [('curr', 'http://www.wikidata.org/entity/Q25344'), ('name', 'Swiss franc'), ('totalPopulation', '8503939')]
# [('curr', 'http://www.wikidata.org/entity/Q25417'), ('name', 'Danish krone'), ('totalPopulation', '5827463')]
# [('curr', 'http://www.wikidata.org/entity/Q1472704'), ('name', 'New Zealand dollar'), ('totalPopulation', '5112300')]
# [('curr', 'http://www.wikidata.org/entity/Q26365'), ('name', 'Eastern Caribbean dollar'), ('totalPopulation', '627848')]
# 12

# %%
# return object linked by country property from United States dollar
queryString = """
SELECT DISTINCT ?obj ?name
WHERE {
   wd:Q4917 wdt:P17 ?obj .
   # ?obj sc:name ?name.
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('obj', 'http://www.wikidata.org/entity/Q30'), ('name', 'United States of America')]
# 1

# %%
# return countries using United States dollar
queryString = """
SELECT DISTINCT ?country ?name
WHERE {
   # ?country wdt:P31/wdt:P279* wd:Q6256;
            wdt:P38 wd:Q4917.
   # ?country sc:name ?name.
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('country', 'http://www.wikidata.org/entity/Q16644'), ('name', 'Northern Mariana Islands')]
# [('country', 'http://www.wikidata.org/entity/Q1014'), ('name', 'Liberia')]
# [('country', 'http://www.wikidata.org/entity/Q16641'), ('name', 'American Samoa')]
# [('country', 'http://www.wikidata.org/entity/Q30'), ('name', 'United States of America')]
# [('country', 'http://www.wikidata.org/entity/Q574'), ('name', 'East Timor')]
# [('country', 'http://www.wikidata.org/entity/Q695'), ('name', 'Palau')]
# [('country', 'http://www.wikidata.org/entity/Q702'), ('name', 'Federated States of Micronesia')]
# [('country', 'http://www.wikidata.org/entity/Q709'), ('name', 'Marshall Islands')]
# [('country', 'http://www.wikidata.org/entity/Q736'), ('name', 'Ecuador')]
# [('country', 'http://www.wikidata.org/entity/Q792'), ('name', 'El Salvador')]
# [('country', 'http://www.wikidata.org/entity/Q804'), ('name', 'Panama')]
# [('country', 'http://www.wikidata.org/entity/Q954'), ('name', 'Zimbabwe')]
# 12

# %%
# return United State's population
queryString = """
SELECT DISTINCT ?obj 
WHERE {
   wd:Q30 wdt:P1082 ?obj .
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('obj', '331449281')]
# 1

# %%
#final query try (wrong code P37)
queryString = """
SELECT ?curr ?name (SUM(?people) AS ?totalPopulation) WHERE {
    # ?country wdt:P37 ?curr.
    # ?country wdt:P31 wd:Q6256.
    # ?country wdt:P1082 ?people.
    {
    SELECT ?curr ?name (COUNT(?country) AS ?totCountries)
    WHERE {
       # ?country wdt:P31 wd:Q6256;
                wdt:P38 ?curr.

       # get the label
       # ?curr sc:name ?name.
    }
    GROUP BY ?curr ?name 
    HAVING (COUNT(?country) >= 2)
    }
}
GROUP BY ?curr ?name 
ORDER BY DESC (?totalPopulation)
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# Empty

# %%
#final query try 
queryString = """
SELECT ?curr ?name (SUM(?people) AS ?totalPeople) WHERE {
    # ?country wdt:P38 ?curr.
    # ?country wdt:P31 wd:Q6256.
    # ?country wdt:P1082 ?people.
    {
    SELECT ?curr ?name (COUNT(?country) AS ?totCountries)
    WHERE {
       # ?country wdt:P31 wd:Q6256;
                wdt:P38 ?curr.

       # get the label
       # ?curr sc:name ?name.
    }
    GROUP BY ?curr ?name 
    HAVING (COUNT(?country) >= 2)
    }
}
GROUP BY ?curr ?name 
ORDER BY DESC (?totalPeople)
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('curr', 'http://www.wikidata.org/entity/Q4917'), ('name', 'United States dollar'), ('totalPeople', '377344239')]
# [('curr', 'http://www.wikidata.org/entity/Q4916'), ('name', 'euro'), ('totalPeople', '211557018')]
# [('curr', 'http://www.wikidata.org/entity/Q861690'), ('name', 'West African CFA franc'), ('totalPeople', '121487314')]
# [('curr', 'http://www.wikidata.org/entity/Q188608'), ('name', 'Iranian rial'), ('totalPeople', '79966230')]
# [('curr', 'http://www.wikidata.org/entity/Q25224'), ('name', 'pound sterling'), ('totalPeople', '69135273')]
# [('curr', 'http://www.wikidata.org/entity/Q181907'), ('name', 'South African rand'), ('totalPeople', '64389483')]
# [('curr', 'http://www.wikidata.org/entity/Q847739'), ('name', 'Central African CFA franc'), ('totalPeople', '49451308')]
# [('curr', 'http://www.wikidata.org/entity/Q259502'), ('name', 'Australian dollar'), ('totalPeople', '24656582')]
# [('curr', 'http://www.wikidata.org/entity/Q25417'), ('name', 'Danish krone'), ('totalPeople', '11758450')]
# [('curr', 'http://www.wikidata.org/entity/Q25344'), ('name', 'Swiss franc'), ('totalPeople', '8503939')]
# [('curr', 'http://www.wikidata.org/entity/Q1472704'), ('name', 'New Zealand dollar'), ('totalPeople', '5131346')]
# [('curr', 'http://www.wikidata.org/entity/Q26365'), ('name', 'Eastern Caribbean dollar'), ('totalPeople', '627848')]
# 12

# %%
#final query try on updated task 6
queryString = """
SELECT ?currency ?currencyName (SUM(?people) AS ?totalPeople) WHERE {
    # ?currency ^wdt:P38 ?country.
    # ?country wdt:P31 ?class.
    # ?class wdt:P279* wd:Q6256.
    # ?country wdt:P1082 ?people.
    {
            SELECT DISTINCT ?currency ?currencyName
            WHERE {
               # ?country wdt:P31 ?class;
                        wdt:P38 ?currency.
               # ?class wdt:P279* wd:Q6256.

               # get the label
               # ?currency sc:name ?currencyName.
            }
    GROUP BY ?currency ?currencyName
    HAVING (COUNT( ?country) >= 2)
    }
}
GROUP BY ?currency ?currencyName 
ORDER BY DESC (?totalPeople)
LIMIT 50
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('currency', 'http://www.wikidata.org/entity/Q25224'), ('currencyName', 'pound sterling'), ('totalPeople', '6106448730')]
# [('currency', 'http://www.wikidata.org/entity/Q39099'), ('currencyName', 'renminbi'), ('totalPeople', '5773989512')]
# [('currency', 'http://www.wikidata.org/entity/Q80524'), ('currencyName', 'Indian rupee'), ('totalPeople', '5304372988')]
# [('currency', 'http://www.wikidata.org/entity/Q41588'), ('currencyName', 'rupiah'), ('totalPeople', '2165004544')]
# [('currency', 'http://www.wikidata.org/entity/Q4916'), ('currencyName', 'euro'), ('totalPeople', '1652751098')]
# [('currency', 'http://www.wikidata.org/entity/Q4917'), ('currencyName', 'United States dollar'), ('totalPeople', '1553365694')]
# [('currency', 'http://www.wikidata.org/entity/Q199462'), ('currencyName', 'Egyptian pound'), ('totalPeople', '973490270')]
# [('currency', 'http://www.wikidata.org/entity/Q8146'), ('currencyName', 'Japanese yen'), ('totalPeople', '954147390')]
# [('currency', 'http://www.wikidata.org/entity/Q188289'), ('currencyName', 'Pakistani rupee'), ('totalPeople', '866261272')]
# [('currency', 'http://www.wikidata.org/entity/Q173117'), ('currencyName', 'Brazilian real'), ('totalPeople', '853270556')]
# [('currency', 'http://www.wikidata.org/entity/Q172872'), ('currencyName', 'Turkish lira'), ('totalPeople', '836770872')]
# [('currency', 'http://www.wikidata.org/entity/Q203567'), ('currencyName', 'Nigerian naira'), ('totalPeople', '763545244')]
# [('currency', 'http://www.wikidata.org/entity/Q194453'), ('currencyName', 'Bangladeshi taka'), ('totalPeople', '663100000')]
# [('currency', 'http://www.wikidata.org/entity/Q17193'), ('currencyName', 'Philippine peso'), ('totalPeople', '654212058')]
# [('currency', 'http://www.wikidata.org/entity/Q4077050'), ('currencyName', 'Balysh'), ('totalPeople', '640000000')]
# [('currency', 'http://www.wikidata.org/entity/Q206243'), ('currencyName', 'birr'), ('totalPeople', '629744628')]
# [('currency', 'http://www.wikidata.org/entity/Q861690'), ('currencyName', 'West African CFA franc'), ('totalPeople', '606963912')]
# [('currency', 'http://www.wikidata.org/entity/Q4730'), ('currencyName', 'Mexican peso'), ('totalPeople', '499109296')]
# [('currency', 'http://www.wikidata.org/entity/Q1370372'), ('currencyName', 'Spanish real'), ('totalPeople', '480000000')]
# [('currency', 'http://www.wikidata.org/entity/Q189097'), ('currencyName', 'peseta'), ('totalPeople', '480000000')]
# [('currency', 'http://www.wikidata.org/entity/Q15039722'), ('currencyName', 'spanish dollar'), ('totalPeople', '480000000')]
# [('currency', 'http://www.wikidata.org/entity/Q192090'), ('currencyName', 'Vietnamese dong'), ('totalPeople', '378640000')]
# [('currency', 'http://www.wikidata.org/entity/Q199471'), ('currencyName', 'Afghan afghani'), ('totalPeople', '358234802')]
# [('currency', 'http://www.wikidata.org/entity/Q1275499'), ('currencyName', 'East African shilling'), ('totalPeople', '357957766')]
# [('currency', 'http://www.wikidata.org/entity/Q4734'), ('currencyName', 'Congolese franc'), ('totalPeople', '347162268')]
# [('currency', 'http://www.wikidata.org/entity/Q199674'), ('currencyName', 'Algerian dinar'), ('totalPeople', '330545136')]
# [('currency', 'http://www.wikidata.org/entity/Q188608'), ('currencyName', 'Iranian rial'), ('totalPeople', '319864920')]
# [('currency', 'http://www.wikidata.org/entity/Q178843'), ('currencyName', 'rupee'), ('totalPeople', '300000000')]
# [('currency', 'http://www.wikidata.org/entity/Q41044'), ('currencyName', 'Russian ruble'), ('totalPeople', '293715808')]
# [('currency', 'http://www.wikidata.org/entity/Q200192'), ('currencyName', 'Moroccan dirham'), ('totalPeople', '288233104')]
# [('currency', 'http://www.wikidata.org/entity/Q177882'), ('currencyName', 'baht'), ('totalPeople', '263726200')]
# [('currency', 'http://www.wikidata.org/entity/Q181907'), ('currencyName', 'South African rand'), ('totalPeople', '262024610')]
# [('currency', 'http://www.wikidata.org/entity/Q4598'), ('currencyName', 'Ugandan shilling'), ('totalPeople', '257177748')]
# [('currency', 'http://www.wikidata.org/entity/Q847739'), ('currencyName', 'Central African CFA franc'), ('totalPeople', '244664546')]
# [('currency', 'http://www.wikidata.org/entity/Q4589'), ('currencyName', 'Tanzanian shilling'), ('totalPeople', '229240076')]
# [('currency', 'http://www.wikidata.org/entity/Q155009'), ('currencyName', 'Reichsmark'), ('totalPeople', '219036366')]
# [('currency', 'http://www.wikidata.org/entity/Q201875'), ('currencyName', 'kyat'), ('totalPeople', '213482436')]
# [('currency', 'http://www.wikidata.org/entity/Q202040'), ('currencyName', 'South Korean won'), ('totalPeople', '205864804')]
# [('currency', 'http://www.wikidata.org/entity/Q3867091'), ('currencyName', 'Korean mun'), ('totalPeople', '205864804')]
# [('currency', 'http://www.wikidata.org/entity/Q487888'), ('currencyName', 'Uzbekistani som'), ('totalPeople', '201423654')]
# [('currency', 'http://www.wikidata.org/entity/Q244819'), ('currencyName', 'Colombian peso'), ('totalPeople', '196262460')]
# [('currency', 'http://www.wikidata.org/entity/Q202882'), ('currencyName', 'Kenyan shilling'), ('totalPeople', '193872552')]
# [('currency', 'http://www.wikidata.org/entity/Q202895'), ('currencyName', 'Nepalese rupee'), ('totalPeople', '181967262')]
# [('currency', 'http://www.wikidata.org/entity/Q199578'), ('currencyName', 'Argentine peso'), ('totalPeople', '179754848')]
# [('currency', 'http://www.wikidata.org/entity/Q271206'), ('currencyName', 'Sudanese pound'), ('totalPeople', '162133320')]
# [('currency', 'http://www.wikidata.org/entity/Q123213'), ('currencyName', 'złoty'), ('totalPeople', '153530304')]
# [('currency', 'http://www.wikidata.org/entity/Q4584'), ('currencyName', 'ariary'), ('totalPeople', '153425370')]
# [('currency', 'http://www.wikidata.org/entity/Q193094'), ('currencyName', 'Iraqi dinar'), ('totalPeople', '153098472')]
# [('currency', 'http://www.wikidata.org/entity/Q106720'), ('currencyName', 'North Korean won'), ('totalPeople', '152945790')]
# [('currency', 'http://www.wikidata.org/entity/Q1104069'), ('currencyName', 'Canadian dollar'), ('totalPeople', '151579196')]
# 50

# %%
#return which countries use dinar currency
queryString = """
SELECT DISTINCT ?country ?name 
WHERE {
   # ?country wdt:P31 ?class;
            wdt:P38 wd:Q191830.
   # ?class wdt:P279* wd:Q6256.
   
   # get the label
   # ?country sc:name ?name.
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('country', 'http://www.wikidata.org/entity/Q484195'), ('name', 'Timurid Empire')]
# [('country', 'http://www.wikidata.org/entity/Q160307'), ('name', 'Fatimid Caliphate')]
# 2

# %%
#return which countries use pound sterling currency
queryString = """
SELECT DISTINCT ?country ?name 
WHERE {
   # ?country wdt:P31 ?class;
            wdt:P38 wd:Q25224.
   # ?class wdt:P279* wd:Q6256.
   
   # get the label
   # ?country sc:name ?name.
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('country', 'http://www.wikidata.org/entity/Q145'), ('name', 'United Kingdom')]
# [('country', 'http://www.wikidata.org/entity/Q25'), ('name', 'Wales')]
# [('country', 'http://www.wikidata.org/entity/Q8680'), ('name', 'British Empire')]
# 3

# %%
#return population for Wales
queryString = """
SELECT ?population
WHERE {
   
   wd:Q25 wdt:P1082 ?population.
   
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('population', '3113000')]
# 1

# %%
#return population for British Empire
queryString = """
SELECT ?population
WHERE {
   
   wd:Q8680 wdt:P1082 ?population.
   
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('population', '680000000')]
# 1

# %%
#return what British Empire is instance of
queryString = """
SELECT ?obj ?name
WHERE {
   
   wd:Q8680 wdt:P31 ?obj.
   # ?obj sc:name ?name.
   
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('obj', 'http://www.wikidata.org/entity/Q3024240'), ('name', 'historical country')]
# [('obj', 'http://www.wikidata.org/entity/Q48349'), ('name', 'empire')]
# [('obj', 'http://www.wikidata.org/entity/Q1211369'), ('name', 'the empire on which the sun never sets')]
# 3

# %%
#return subclasses of country
queryString = """
SELECT ?s ?name
WHERE {
   # ?s wdt:P279 wd:Q6256.
   # ?s sc:name ?name.
   
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('s', 'http://www.wikidata.org/entity/Q28864179'), ('name', 'proposed country')]
# [('s', 'http://www.wikidata.org/entity/Q2281140'), ('name', 'safe country of origin')]
# [('s', 'http://www.wikidata.org/entity/Q188800'), ('name', 'personal union')]
# [('s', 'http://www.wikidata.org/entity/Q1323642'), ('name', 'transcontinental country')]
# [('s', 'http://www.wikidata.org/entity/Q132453'), ('name', 'developed country')]
# [('s', 'http://www.wikidata.org/entity/Q177323'), ('name', 'developing country')]
# [('s', 'http://www.wikidata.org/entity/Q5170193'), ('name', 'core country')]
# [('s', 'http://www.wikidata.org/entity/Q63441421'), ('name', 'high-income country')]
# [('s', 'http://www.wikidata.org/entity/Q160381'), ('name', 'Western world')]
# [('s', 'http://www.wikidata.org/entity/Q112099'), ('name', 'island nation')]
# [('s', 'http://www.wikidata.org/entity/Q123480'), ('name', 'landlocked country')]
# [('s', 'http://www.wikidata.org/entity/Q3624078'), ('name', 'sovereign state')]
# [('s', 'http://www.wikidata.org/entity/Q51576574'), ('name', 'Mediterranean country')]
# [('s', 'http://www.wikidata.org/entity/Q11396118'), ('name', 'divided country')]
# [('s', 'http://www.wikidata.org/entity/Q1501897'), ('name', 'Generality Lands')]
# [('s', 'http://www.wikidata.org/entity/Q1454602'), ('name', 'low-income country')]
# [('s', 'http://www.wikidata.org/entity/Q1093720'), ('name', 'real union')]
# [('s', 'http://www.wikidata.org/entity/Q331644'), ('name', 'Khanate')]
# [('s', 'http://www.wikidata.org/entity/Q1151616'), ('name', 'stateless nation')]
# [('s', 'http://www.wikidata.org/entity/Q7449317'), ('name', 'semi-periphery countries')]
# [('s', 'http://www.wikidata.org/entity/Q11495981'), ('name', 'victorious country')]
# [('s', 'http://www.wikidata.org/entity/Q831048'), ('name', 'Nassau-Hadamar')]
# [('s', 'http://www.wikidata.org/entity/Q66724388'), ('name', 'autonomous country within the Kingdom of Denmark')]
# [('s', 'http://www.wikidata.org/entity/Q25449457'), ('name', 'continental country')]
# [('s', 'http://www.wikidata.org/entity/Q5367717'), ('name', 'shinkoku')]
# [('s', 'http://www.wikidata.org/entity/Q1641089'), ('name', 'Multinational state')]
# [('s', 'http://www.wikidata.org/entity/Q2639564'), ('name', 'low-wage country')]
# [('s', 'http://www.wikidata.org/entity/Q6726158'), ('name', 'Independent country')]
# [('s', 'http://www.wikidata.org/entity/Q1538989'), ('name', 'megadiverse country')]
# [('s', 'http://www.wikidata.org/entity/Q66903706'), ('name', 'banana producing countries')]
# [('s', 'http://www.wikidata.org/entity/Q3500085'), ('name', 'periphery country')]
# [('s', 'http://www.wikidata.org/entity/Q3373662'), ('name', 'French-speaking country')]
# 32

# %%
#return objects linked by country property to euro
queryString = """
SELECT ?o ?name
WHERE {
   wd:Q4916 wdt:P17 ?o.
   # ?o sc:name ?name.
   
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('o', 'http://www.wikidata.org/entity/Q142'), ('name', 'France')]
# [('o', 'http://www.wikidata.org/entity/Q183'), ('name', 'Germany')]
# [('o', 'http://www.wikidata.org/entity/Q191'), ('name', 'Estonia')]
# [('o', 'http://www.wikidata.org/entity/Q211'), ('name', 'Latvia')]
# [('o', 'http://www.wikidata.org/entity/Q214'), ('name', 'Slovakia')]
# [('o', 'http://www.wikidata.org/entity/Q215'), ('name', 'Slovenia')]
# [('o', 'http://www.wikidata.org/entity/Q228'), ('name', 'Andorra')]
# [('o', 'http://www.wikidata.org/entity/Q229'), ('name', 'Cyprus')]
# [('o', 'http://www.wikidata.org/entity/Q233'), ('name', 'Malta')]
# [('o', 'http://www.wikidata.org/entity/Q235'), ('name', 'Monaco')]
# [('o', 'http://www.wikidata.org/entity/Q237'), ('name', 'Vatican City')]
# [('o', 'http://www.wikidata.org/entity/Q238'), ('name', 'San Marino')]
# [('o', 'http://www.wikidata.org/entity/Q27'), ('name', 'Ireland')]
# [('o', 'http://www.wikidata.org/entity/Q29'), ('name', 'Spain')]
# [('o', 'http://www.wikidata.org/entity/Q31'), ('name', 'Belgium')]
# [('o', 'http://www.wikidata.org/entity/Q32'), ('name', 'Luxembourg')]
# [('o', 'http://www.wikidata.org/entity/Q33'), ('name', 'Finland')]
# [('o', 'http://www.wikidata.org/entity/Q37'), ('name', 'Lithuania')]
# [('o', 'http://www.wikidata.org/entity/Q38'), ('name', 'Italy')]
# [('o', 'http://www.wikidata.org/entity/Q40'), ('name', 'Austria')]
# [('o', 'http://www.wikidata.org/entity/Q41'), ('name', 'Greece')]
# [('o', 'http://www.wikidata.org/entity/Q45'), ('name', 'Portugal')]
# [('o', 'http://www.wikidata.org/entity/Q55'), ('name', 'Netherlands')]
# 23

# %%
# return countries currently using euro and their population
queryString = """
SELECT DISTINCT ?s ?name ?people
WHERE {
   # ?s wdt:P31/wdt:P279* wd:Q6256;
      wdt:P38 wd:Q4916.
   # ?s wdt:P1082 ?people.
   # ?s sc:name ?name.
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('s', 'http://www.wikidata.org/entity/Q142'), ('name', 'France'), ('people', '67063703')]
# [('s', 'http://www.wikidata.org/entity/Q183'), ('name', 'Germany'), ('people', '83149300')]
# [('s', 'http://www.wikidata.org/entity/Q191'), ('name', 'Estonia'), ('people', '1324820')]
# [('s', 'http://www.wikidata.org/entity/Q211'), ('name', 'Latvia'), ('people', '1909000')]
# [('s', 'http://www.wikidata.org/entity/Q214'), ('name', 'Slovakia'), ('people', '5397036')]
# [('s', 'http://www.wikidata.org/entity/Q215'), ('name', 'Slovenia'), ('people', '2066880')]
# [('s', 'http://www.wikidata.org/entity/Q228'), ('name', 'Andorra'), ('people', '78151')]
# [('s', 'http://www.wikidata.org/entity/Q229'), ('name', 'Cyprus'), ('people', '1141166')]
# [('s', 'http://www.wikidata.org/entity/Q233'), ('name', 'Malta'), ('people', '465292')]
# [('s', 'http://www.wikidata.org/entity/Q235'), ('name', 'Monaco'), ('people', '38695')]
# [('s', 'http://www.wikidata.org/entity/Q236'), ('name', 'Montenegro'), ('people', '622359')]
# [('s', 'http://www.wikidata.org/entity/Q237'), ('name', 'Vatican City'), ('people', '1000')]
# [('s', 'http://www.wikidata.org/entity/Q238'), ('name', 'San Marino'), ('people', '33400')]
# [('s', 'http://www.wikidata.org/entity/Q27'), ('name', 'Ireland'), ('people', '4761865')]
# [('s', 'http://www.wikidata.org/entity/Q29'), ('name', 'Spain'), ('people', '46733038')]
# [('s', 'http://www.wikidata.org/entity/Q29999'), ('name', 'Kingdom of the Netherlands'), ('people', '17100715')]
# [('s', 'http://www.wikidata.org/entity/Q31'), ('name', 'Belgium'), ('people', '11431406')]
# [('s', 'http://www.wikidata.org/entity/Q32'), ('name', 'Luxembourg'), ('people', '626108')]
# [('s', 'http://www.wikidata.org/entity/Q33'), ('name', 'Finland'), ('people', '5501043')]
# [('s', 'http://www.wikidata.org/entity/Q37'), ('name', 'Lithuania'), ('people', '2790842')]
# [('s', 'http://www.wikidata.org/entity/Q38'), ('name', 'Italy'), ('people', '60317000')]
# [('s', 'http://www.wikidata.org/entity/Q40'), ('name', 'Austria'), ('people', '8809212')]
# [('s', 'http://www.wikidata.org/entity/Q41'), ('name', 'Greece'), ('people', '10760421')]
# [('s', 'http://www.wikidata.org/entity/Q45'), ('name', 'Portugal'), ('people', '10347892')]
# [('s', 'http://www.wikidata.org/entity/Q55'), ('name', 'Netherlands'), ('people', '17282163')]
# 25

# %%
#return objects linked by country property to pound sterling
queryString = """
SELECT ?o ?name
WHERE {
   wd:Q25224 wdt:P17 ?o.
   # ?o sc:name ?name.
   
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('o', 'http://www.wikidata.org/entity/Q145'), ('name', 'United Kingdom')]
# 1

# %%
#final query try on updated task 6
queryString = """
SELECT ?currency ?currencyName (SUM(?people) AS ?totalPeople) WHERE {
    # ?currency wdt:P17 ?country.
    # ?country wdt:P31 ?class.
    # ?class wdt:P279* wd:Q6256.
    # ?country wdt:P1082 ?people.
    {
            SELECT DISTINCT ?currency ?currencyName
            WHERE {
               # ?country wdt:P31 ?class.
               # ?currency wdt:P31 wd:Q8142.
               # ?currency wdt:P17 ?country.
               # ?class wdt:P279* wd:Q6256.

               # get the label
               # ?currency sc:name ?currencyName.
            }
    GROUP BY ?currency ?currencyName
    HAVING (COUNT(DISTINCT ?country) >= 2)
    }
}
GROUP BY ?currency ?currencyName 
ORDER BY DESC (?totalPeople)
LIMIT 50
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('currency', 'http://www.wikidata.org/entity/Q4916'), ('currencyName', 'euro'), ('totalPeople', '1545167936')]
# [('currency', 'http://www.wikidata.org/entity/Q5527593'), ('currencyName', 'Gaucho'), ('totalPeople', '1033025404')]
# [('currency', 'http://www.wikidata.org/entity/Q172872'), ('currencyName', 'Turkish lira'), ('totalPeople', '836770872')]
# [('currency', 'http://www.wikidata.org/entity/Q861690'), ('currencyName', 'West African CFA franc'), ('totalPeople', '606963912')]
# [('currency', 'http://www.wikidata.org/entity/Q184172'), ('currencyName', 'French franc'), ('totalPeople', '536899618')]
# [('currency', 'http://www.wikidata.org/entity/Q1415602'), ('currencyName', 'Kopeck'), ('totalPeople', '378725400')]
# [('currency', 'http://www.wikidata.org/entity/Q847739'), ('currencyName', 'Central African CFA franc'), ('totalPeople', '244664546')]
# [('currency', 'http://www.wikidata.org/entity/Q3658911'), ('currencyName', 'Carlino'), ('totalPeople', '243129168')]
# [('currency', 'http://www.wikidata.org/entity/Q1072248'), ('currencyName', 'Rwanda and Burundi franc'), ('totalPeople', '142433922')]
# [('currency', 'http://www.wikidata.org/entity/Q189097'), ('currencyName', 'peseta'), ('totalPeople', '96314058')]
# [('currency', 'http://www.wikidata.org/entity/Q56374559'), ('currencyName', 'Manat'), ('totalPeople', '55361154')]
# [('currency', 'http://www.wikidata.org/entity/Q25344'), ('currencyName', 'Swiss franc'), ('totalPeople', '34015756')]
# [('currency', 'http://www.wikidata.org/entity/Q26365'), ('currencyName', 'Eastern Caribbean dollar'), ('totalPeople', '4874934')]
# 13

# %%
#final query try
queryString = """    
 SELECT ?currency ?currencyName (SUM( ?people) AS ?totalPeople) WHERE {    
    # ?country wdt:P38 ?currency.
    # ?country wdt:P31 ?class.
    # ?country wdt:P1082 ?people.
    FILTER(NOT EXISTS {?country wdt:P31 wd:Q3024240.} && NOT EXISTS {?country wdt:P1366 ?o.}
                    && NOT EXISTS {?country wdt:P31 wd:Q417175.} && EXISTS{?class wdt:P279* wd:Q6256.})
        {
        SELECT ?currency ?currencyName  WHERE {
           # ?country wdt:P31 ?class;
                     wdt:P38 ?currency.
           # ?currency wdt:P31 wd:Q8142.
           FILTER(NOT EXISTS {?country wdt:P31 wd:Q3024240.} && NOT EXISTS {?country wdt:P1366 ?o.}
                    && NOT EXISTS {?country wdt:P31 wd:Q417175.} && EXISTS{?class wdt:P279* wd:Q6256.})

           # get the label
           # ?currency sc:name ?currencyName.
           # ?country sc:name ?countryName.
        } 
        GROUP BY ?currency ?currencyName
        HAVING ( COUNT(DISTINCT ?country) >= 2 )
        }
    }
    GROUP BY ?currency ?currencyName
    ORDER BY DESC (?totalPeople)
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('currency', 'http://www.wikidata.org/entity/Q4917'), ('currencyName', 'United States dollar'), ('totalPeople', '776682847')]
# [('currency', 'http://www.wikidata.org/entity/Q4916'), ('currencyName', 'euro'), ('totalPeople', '707387342')]
# [('currency', 'http://www.wikidata.org/entity/Q172872'), ('currencyName', 'Turkish lira'), ('totalPeople', '334771074')]
# [('currency', 'http://www.wikidata.org/entity/Q25224'), ('currencyName', 'pound sterling'), ('totalPeople', '333224365')]
# [('currency', 'http://www.wikidata.org/entity/Q861690'), ('currencyName', 'West African CFA franc'), ('totalPeople', '303481956')]
# [('currency', 'http://www.wikidata.org/entity/Q41044'), ('currencyName', 'Russian ruble'), ('totalPeople', '146857904')]
# [('currency', 'http://www.wikidata.org/entity/Q181907'), ('currencyName', 'South African rand'), ('totalPeople', '124312288')]
# [('currency', 'http://www.wikidata.org/entity/Q847739'), ('currencyName', 'Central African CFA franc'), ('totalPeople', '122332273')]
# [('currency', 'http://www.wikidata.org/entity/Q259502'), ('currencyName', 'Australian dollar'), ('totalPeople', '73980938')]
# [('currency', 'http://www.wikidata.org/entity/Q25417'), ('currencyName', 'Danish krone'), ('totalPeople', '29249477')]
# [('currency', 'http://www.wikidata.org/entity/Q1472704'), ('currencyName', 'New Zealand dollar'), ('totalPeople', '20487292')]
# [('currency', 'http://www.wikidata.org/entity/Q25344'), ('currencyName', 'Swiss franc'), ('totalPeople', '17007878')]
# [('currency', 'http://www.wikidata.org/entity/Q130498'), ('currencyName', 'Armenian dram'), ('totalPeople', '3077050')]
# [('currency', 'http://www.wikidata.org/entity/Q26365'), ('currencyName', 'Eastern Caribbean dollar'), ('totalPeople', '2437467')]
# 14

# %%
#add distinct on SUM
queryString = """    
 SELECT ?currency ?currencyName (SUM(DISTINCT ?people) AS ?totalPeople) WHERE {    
    # ?country wdt:P38 ?currency.
    # ?country wdt:P31 ?class.
    # ?country wdt:P1082 ?people.
    FILTER(NOT EXISTS {?country wdt:P31 wd:Q3024240.} && NOT EXISTS {?country wdt:P1366 ?o.}
                    && NOT EXISTS {?country wdt:P31 wd:Q417175.} && EXISTS{?class wdt:P279* wd:Q6256.})
        {
        SELECT ?currency ?currencyName  WHERE {
           # ?country wdt:P31 ?class;
                     wdt:P38 ?currency.
           # ?currency wdt:P31 wd:Q8142.
           FILTER(NOT EXISTS {?country wdt:P31 wd:Q3024240.} && NOT EXISTS {?country wdt:P1366 ?o.}
                    && NOT EXISTS {?country wdt:P31 wd:Q417175.} && EXISTS{?class wdt:P279* wd:Q6256.})

           # get the label
           # ?currency sc:name ?currencyName.
           # ?country sc:name ?countryName.
        } 
        GROUP BY ?currency ?currencyName
        HAVING ( COUNT(DISTINCT ?country) >= 2 )
        }
    }
    GROUP BY ?currency ?currencyName
    ORDER BY DESC (?totalPeople)
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('currency', 'http://www.wikidata.org/entity/Q4917'), ('currencyName', 'United States dollar'), ('totalPeople', '381442826')]
# [('currency', 'http://www.wikidata.org/entity/Q4916'), ('currencyName', 'euro'), ('totalPeople', '342651792')]
# [('currency', 'http://www.wikidata.org/entity/Q41044'), ('currencyName', 'Russian ruble'), ('totalPeople', '146857904')]
# [('currency', 'http://www.wikidata.org/entity/Q861690'), ('currencyName', 'West African CFA franc'), ('totalPeople', '121487314')]
# [('currency', 'http://www.wikidata.org/entity/Q172872'), ('currencyName', 'Turkish lira'), ('totalPeople', '83927988')]
# [('currency', 'http://www.wikidata.org/entity/Q25224'), ('currencyName', 'pound sterling'), ('totalPeople', '69135273')]
# [('currency', 'http://www.wikidata.org/entity/Q181907'), ('currencyName', 'South African rand'), ('totalPeople', '62156144')]
# [('currency', 'http://www.wikidata.org/entity/Q847739'), ('currencyName', 'Central African CFA franc'), ('totalPeople', '52744134')]
# [('currency', 'http://www.wikidata.org/entity/Q259502'), ('currencyName', 'Australian dollar'), ('totalPeople', '24656582')]
# [('currency', 'http://www.wikidata.org/entity/Q25344'), ('currencyName', 'Swiss franc'), ('totalPeople', '8503939')]
# [('currency', 'http://www.wikidata.org/entity/Q25417'), ('currencyName', 'Danish krone'), ('totalPeople', '5883544')]
# [('currency', 'http://www.wikidata.org/entity/Q1472704'), ('currencyName', 'New Zealand dollar'), ('totalPeople', '5131346')]
# [('currency', 'http://www.wikidata.org/entity/Q130498'), ('currencyName', 'Armenian dram'), ('totalPeople', '3077050')]
# [('currency', 'http://www.wikidata.org/entity/Q26365'), ('currencyName', 'Eastern Caribbean dollar'), ('totalPeople', '627848')]
# 14

# %%
#add path instance of / country or subclass of it
queryString = """    
 SELECT ?currency ?currencyName (SUM(DISTINCT ?people) AS ?totalPeople) WHERE {    
    # ?country wdt:P38 ?currency.
    # ?country wdt:P31/wdt:P279* wd:Q6256.
    # ?country wdt:P1082 ?people.
    FILTER(NOT EXISTS {?country wdt:P31 wd:Q3024240.} && NOT EXISTS {?country wdt:P1366 ?o.}
                    && NOT EXISTS {?country wdt:P31 wd:Q417175.})
        {
        SELECT ?currency ?currencyName  WHERE {
           # ?country wdt:P31/wdt:P279* wd:Q6256;
                     wdt:P38 ?currency.
           # ?currency wdt:P31 wd:Q8142.
           FILTER(NOT EXISTS {?country wdt:P31 wd:Q3024240.} && NOT EXISTS {?country wdt:P1366 ?o.}
                    && NOT EXISTS {?country wdt:P31 wd:Q417175.})

           # get the label
           # ?currency sc:name ?currencyName.
           # ?country sc:name ?countryName.
        } 
        GROUP BY ?currency ?currencyName
        HAVING ( COUNT(DISTINCT ?country) >= 2 )
        }
    }
    GROUP BY ?currency ?currencyName
    ORDER BY DESC (?totalPeople)
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('currency', 'http://www.wikidata.org/entity/Q4917'), ('currencyName', 'United States dollar'), ('totalPeople', '381442826')]
# [('currency', 'http://www.wikidata.org/entity/Q4916'), ('currencyName', 'euro'), ('totalPeople', '342651792')]
# [('currency', 'http://www.wikidata.org/entity/Q41044'), ('currencyName', 'Russian ruble'), ('totalPeople', '146857904')]
# [('currency', 'http://www.wikidata.org/entity/Q861690'), ('currencyName', 'West African CFA franc'), ('totalPeople', '121487314')]
# [('currency', 'http://www.wikidata.org/entity/Q172872'), ('currencyName', 'Turkish lira'), ('totalPeople', '83927988')]
# [('currency', 'http://www.wikidata.org/entity/Q25224'), ('currencyName', 'pound sterling'), ('totalPeople', '69135273')]
# [('currency', 'http://www.wikidata.org/entity/Q181907'), ('currencyName', 'South African rand'), ('totalPeople', '62156144')]
# [('currency', 'http://www.wikidata.org/entity/Q847739'), ('currencyName', 'Central African CFA franc'), ('totalPeople', '52744134')]
# [('currency', 'http://www.wikidata.org/entity/Q259502'), ('currencyName', 'Australian dollar'), ('totalPeople', '24656582')]
# [('currency', 'http://www.wikidata.org/entity/Q25344'), ('currencyName', 'Swiss franc'), ('totalPeople', '8503939')]
# [('currency', 'http://www.wikidata.org/entity/Q25417'), ('currencyName', 'Danish krone'), ('totalPeople', '5883544')]
# [('currency', 'http://www.wikidata.org/entity/Q1472704'), ('currencyName', 'New Zealand dollar'), ('totalPeople', '5131346')]
# [('currency', 'http://www.wikidata.org/entity/Q130498'), ('currencyName', 'Armenian dram'), ('totalPeople', '3077050')]
# [('currency', 'http://www.wikidata.org/entity/Q26365'), ('currencyName', 'Eastern Caribbean dollar'), ('totalPeople', '627848')]
# 14

# %%
#return population for United Kingdom and check the sum with the Wales' one
queryString = """
SELECT ?population
WHERE {
   
   wd:Q145 wdt:P1082 ?population.
   
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('population', '66022273')]
# 1

# %%
#subquery don't needed
queryString = """    
SELECT ?currency ?currencyName (SUM(DISTINCT ?people) AS ?totalPeople) (COUNT(DISTINCT ?country) as ?n)  WHERE {    
    # ?country wdt:P38 ?currency.
    # ?country wdt:P31/wdt:P279* wd:Q6256.
    # ?country wdt:P1082 ?people.
    # ?currency wdt:P31 wd:Q8142.
    FILTER(NOT EXISTS {?country wdt:P31 wd:Q3024240.} && NOT EXISTS {?country wdt:P1366 ?o.}
                    && NOT EXISTS {?country wdt:P31 wd:Q417175.})
    # ?currency sc:name ?currencyName.
    # ?country sc:name ?countryName.    
}       
GROUP BY ?currency ?currencyName
HAVING (COUNT(DISTINCT ?country) >= 2)
ORDER BY DESC (?totalPeople)
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('currency', 'http://www.wikidata.org/entity/Q4916'), ('currencyName', 'euro'), ('totalPeople', '1102614348'), ('n', '24')]
# [('currency', 'http://www.wikidata.org/entity/Q4917'), ('currencyName', 'United States dollar'), ('totalPeople', '380364982'), ('n', '15')]
# [('currency', 'http://www.wikidata.org/entity/Q209272'), ('currencyName', 'Uruguayan peso'), ('totalPeople', '267804570'), ('n', '2')]
# [('currency', 'http://www.wikidata.org/entity/Q8146'), ('currencyName', 'Japanese yen'), ('totalPeople', '148744875'), ('n', '2')]
# [('currency', 'http://www.wikidata.org/entity/Q861690'), ('currencyName', 'West African CFA franc'), ('totalPeople', '121487314'), ('n', '8')]
# [('currency', 'http://www.wikidata.org/entity/Q199462'), ('currencyName', 'Egyptian pound'), ('totalPeople', '97798827'), ('n', '2')]
# [('currency', 'http://www.wikidata.org/entity/Q188608'), ('currencyName', 'Iranian rial'), ('totalPeople', '88813012'), ('n', '2')]
# [('currency', 'http://www.wikidata.org/entity/Q172872'), ('currencyName', 'Turkish lira'), ('totalPeople', '83927988'), ('n', '2')]
# [('currency', 'http://www.wikidata.org/entity/Q25224'), ('currencyName', 'pound sterling'), ('totalPeople', '71681387'), ('n', '5')]
# [('currency', 'http://www.wikidata.org/entity/Q847739'), ('currencyName', 'Central African CFA franc'), ('totalPeople', '50779682'), ('n', '6')]
# [('currency', 'http://www.wikidata.org/entity/Q81893'), ('currencyName', 'hryvnia'), ('totalPeople', '44470728'), ('n', '3')]
# [('currency', 'http://www.wikidata.org/entity/Q199674'), ('currencyName', 'Algerian dinar'), ('totalPeople', '42440355'), ('n', '2')]
# [('currency', 'http://www.wikidata.org/entity/Q200192'), ('currencyName', 'Moroccan dirham'), ('totalPeople', '37151351'), ('n', '2')]
# [('currency', 'http://www.wikidata.org/entity/Q259502'), ('currencyName', 'Australian dollar'), ('totalPeople', '24657178'), ('n', '5')]
# [('currency', 'http://www.wikidata.org/entity/Q240468'), ('currencyName', 'Syrian pound'), ('totalPeople', '20499181'), ('n', '2')]
# [('currency', 'http://www.wikidata.org/entity/Q203722'), ('currencyName', 'Jordanian dinar'), ('totalPeople', '15655434'), ('n', '2')]
# [('currency', 'http://www.wikidata.org/entity/Q131309'), ('currencyName', 'new shekel'), ('totalPeople', '12093000'), ('n', '2')]
# [('currency', 'http://www.wikidata.org/entity/Q1104069'), ('currencyName', 'Canadian dollar'), ('totalPeople', '8731034'), ('n', '3')]
# [('currency', 'http://www.wikidata.org/entity/Q25344'), ('currencyName', 'Swiss franc'), ('totalPeople', '8507385'), ('n', '4')]
# [('currency', 'http://www.wikidata.org/entity/Q31015'), ('currencyName', 'Hong Kong dollar'), ('totalPeople', '8067075'), ('n', '2')]
# [('currency', 'http://www.wikidata.org/entity/Q25417'), ('currencyName', 'Danish krone'), ('totalPeople', '5883544'), ('n', '2')]
# [('currency', 'http://www.wikidata.org/entity/Q207024'), ('currencyName', 'Mauritanian ouguiya'), ('totalPeople', '5542397'), ('n', '2')]
# [('currency', 'http://www.wikidata.org/entity/Q1472704'), ('currencyName', 'New Zealand dollar'), ('totalPeople', '5131346'), ('n', '3')]
# [('currency', 'http://www.wikidata.org/entity/Q41044'), ('currencyName', 'Russian ruble'), ('totalPeople', '3652580'), ('n', '10')]
# [('currency', 'http://www.wikidata.org/entity/Q206319'), ('currencyName', 'Brunei dollar'), ('totalPeople', '735697'), ('n', '2')]
# [('currency', 'http://www.wikidata.org/entity/Q26365'), ('currencyName', 'Eastern Caribbean dollar'), ('totalPeople', '627848'), ('n', '6')]
# [('currency', 'http://www.wikidata.org/entity/Q214393'), ('currencyName', 'CFP Franc'), ('totalPeople', '554418'), ('n', '2')]
# [('currency', 'http://www.wikidata.org/entity/Q522701'), ('currencyName', 'Netherlands Antillean guilder'), ('totalPeople', '197469'), ('n', '2')]
# 28

# %%
#pass the country to the outer query
queryString = """    
SELECT ?currency ?currencyName (SUM(DISTINCT ?people) AS ?totalPeople) (COUNT(DISTINCT ?country)as ?n) (GROUP_CONCAT(DISTINCT ?countryName ; separator =", " ) AS ?list) WHERE {    
    # ?country wdt:P1082 ?people.
    {
        SELECT ?country ?countryName ?currency ?currencyName WHERE {    
            # ?country wdt:P38 ?currency.
            # ?country wdt:P31/wdt:P279* wd:Q6256.

            # ?currency wdt:P31 wd:Q8142.
            FILTER(NOT EXISTS {?country wdt:P31 wd:Q3024240.} && NOT EXISTS {?country wdt:P1366 ?o.}
                            && NOT EXISTS {?country wdt:P31 wd:Q417175.})
            # ?currency sc:name ?currencyName.
            # ?country sc:name ?countryName.    
        }
    }
}
GROUP BY ?currency ?currencyName
HAVING (COUNT(DISTINCT ?country) >= 2)
ORDER BY DESC (?totalPeople)
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('currency', 'http://www.wikidata.org/entity/Q4917'), ('currencyName', 'United States dollar'), ('totalPeople', '381442826'), ('n', '12'), ('list', 'American Samoa, East Timor, Ecuador, El Salvador, Federated States of Micronesia, Liberia, Marshall Islands, Northern Mariana Islands, Palau, Panama, United States of America, Zimbabwe')]
# [('currency', 'http://www.wikidata.org/entity/Q4916'), ('currencyName', 'euro'), ('totalPeople', '342651792'), ('n', '24'), ('list', 'Andorra, Austria, Belgium, Cyprus, Estonia, Finland, France, Germany, Greece, Ireland, Italy, Latvia, Lithuania, Luxembourg, Malta, Monaco, Montenegro, Netherlands, Portugal, San Marino, Slovakia, Slovenia, Spain, Vatican City')]
# [('currency', 'http://www.wikidata.org/entity/Q41044'), ('currencyName', 'Russian ruble'), ('totalPeople', '146857904'), ('n', '2'), ('list', 'Russia, South Ossetia')]
# [('currency', 'http://www.wikidata.org/entity/Q861690'), ('currencyName', 'West African CFA franc'), ('totalPeople', '121487314'), ('n', '8'), ('list', 'Benin, Burkina Faso, Guinea-Bissau, Ivory Coast, Mali, Niger, Senegal, Togo')]
# [('currency', 'http://www.wikidata.org/entity/Q172872'), ('currencyName', 'Turkish lira'), ('totalPeople', '83927988'), ('n', '2'), ('list', 'Turkey, Turkish Republic of Northern Cyprus')]
# [('currency', 'http://www.wikidata.org/entity/Q25224'), ('currencyName', 'pound sterling'), ('totalPeople', '69135273'), ('n', '2'), ('list', 'United Kingdom, Wales')]
# [('currency', 'http://www.wikidata.org/entity/Q181907'), ('currencyName', 'South African rand'), ('totalPeople', '62156144'), ('n', '2'), ('list', 'Namibia, South Africa')]
# [('currency', 'http://www.wikidata.org/entity/Q847739'), ('currencyName', 'Central African CFA franc'), ('totalPeople', '52744134'), ('n', '6'), ('list', 'Cameroon, Central African Republic, Chad, Equatorial Guinea, Gabon, Republic of the Congo')]
# [('currency', 'http://www.wikidata.org/entity/Q259502'), ('currencyName', 'Australian dollar'), ('totalPeople', '24656582'), ('n', '4'), ('list', 'Australia, Kiribati, Nauru, Tuvalu')]
# [('currency', 'http://www.wikidata.org/entity/Q25344'), ('currencyName', 'Swiss franc'), ('totalPeople', '8503939'), ('n', '2'), ('list', 'Liechtenstein, Switzerland')]
# [('currency', 'http://www.wikidata.org/entity/Q25417'), ('currencyName', 'Danish krone'), ('totalPeople', '5883544'), ('n', '2'), ('list', 'Denmark, Greenland')]
# [('currency', 'http://www.wikidata.org/entity/Q1472704'), ('currencyName', 'New Zealand dollar'), ('totalPeople', '5131346'), ('n', '3'), ('list', 'Cook Islands, New Zealand, Niue')]
# [('currency', 'http://www.wikidata.org/entity/Q130498'), ('currencyName', 'Armenian dram'), ('totalPeople', '3077050'), ('n', '2'), ('list', 'Armenia, Republic of Artsakh')]
# [('currency', 'http://www.wikidata.org/entity/Q26365'), ('currencyName', 'Eastern Caribbean dollar'), ('totalPeople', '627848'), ('n', '6'), ('list', 'Antigua and Barbuda, Dominica, Grenada, Saint Kitts and Nevis, Saint Lucia, Saint Vincent and the Grenadines')]
# 14

# %% [markdown]
# Final query for this task

# %%
#Consider the currencies obtained in task 6, for each currency return the number of people using that currency 
#(hint: consider the maximum popolation available for each country).
# write your final query
queryString = """    
SELECT ?currency ?currencyName (SUM(DISTINCT ?people) AS ?totalPeople) WHERE {    
    # ?country wdt:P1082 ?people.
    {
        SELECT ?country ?currency ?currencyName WHERE {    
            # ?country wdt:P38 ?currency.
            # ?country wdt:P31/wdt:P279* wd:Q6256.
            # ?currency wdt:P31 wd:Q8142.
            FILTER(NOT EXISTS {?country wdt:P31 wd:Q3024240.} && NOT EXISTS {?country wdt:P1366 ?o.}
                            && NOT EXISTS {?country wdt:P31 wd:Q417175.})
            # ?currency sc:name ?currencyName.   
        }
    }
}
GROUP BY ?currency ?currencyName
HAVING (COUNT(DISTINCT ?country) >= 2)
ORDER BY DESC (?totalPeople)
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('currency', 'http://www.wikidata.org/entity/Q4917'), ('currencyName', 'United States dollar'), ('totalPeople', '381442826')]
# [('currency', 'http://www.wikidata.org/entity/Q4916'), ('currencyName', 'euro'), ('totalPeople', '342651792')]
# [('currency', 'http://www.wikidata.org/entity/Q41044'), ('currencyName', 'Russian ruble'), ('totalPeople', '146857904')]
# [('currency', 'http://www.wikidata.org/entity/Q861690'), ('currencyName', 'West African CFA franc'), ('totalPeople', '121487314')]
# [('currency', 'http://www.wikidata.org/entity/Q172872'), ('currencyName', 'Turkish lira'), ('totalPeople', '83927988')]
# [('currency', 'http://www.wikidata.org/entity/Q25224'), ('currencyName', 'pound sterling'), ('totalPeople', '69135273')]
# [('currency', 'http://www.wikidata.org/entity/Q181907'), ('currencyName', 'South African rand'), ('totalPeople', '62156144')]
# [('currency', 'http://www.wikidata.org/entity/Q847739'), ('currencyName', 'Central African CFA franc'), ('totalPeople', '52744134')]
# [('currency', 'http://www.wikidata.org/entity/Q259502'), ('currencyName', 'Australian dollar'), ('totalPeople', '24656582')]
# [('currency', 'http://www.wikidata.org/entity/Q25344'), ('currencyName', 'Swiss franc'), ('totalPeople', '8503939')]
# [('currency', 'http://www.wikidata.org/entity/Q25417'), ('currencyName', 'Danish krone'), ('totalPeople', '5883544')]
# [('currency', 'http://www.wikidata.org/entity/Q1472704'), ('currencyName', 'New Zealand dollar'), ('totalPeople', '5131346')]
# [('currency', 'http://www.wikidata.org/entity/Q130498'), ('currencyName', 'Armenian dram'), ('totalPeople', '3077050')]
# [('currency', 'http://www.wikidata.org/entity/Q26365'), ('currencyName', 'Eastern Caribbean dollar'), ('totalPeople', '627848')]
# 14

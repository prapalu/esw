# %% [markdown]
# # General instructions
#
# The goal of the project is to materialize a set of **exploratory workloads** over a real-world, large-scale,  open-domain KG: [WikiData](https://www.wikidata.org/wiki/Wikidata:Main_Page)
#
# An exploratory workload  is composed by a set of queries, where each query is related to the information obtained previously.
#
# An exploratory workload starts with a usually vague, open ended question, and does not assume the person issuing the workload has a clear understanding of the data contained in the target database or its structure.
#
# Remeber that:
#
# 1. All the queries must run in the python notebook
# 2. You can use classes and properties only if you find them via a SPARQL query that must be present in the notebook
# 3. You do not delete useless queries. Keep everything that is synthatically valid
#
# ```
# ?p <http://schema.org/name> ?name .
# ```
#
#     is the BGP returning a human-readable name of a property or a class in Wikidata.

# %%
## SETUP used later

from SPARQLWrapper import SPARQLWrapper, JSON


prefixString = """
##-b39a9416e4-##
PREFIX wd: <http://www.wikidata.org/entity/> 
PREFIX wdt: <http://www.wikidata.org/prop/direct/> 
PREFIX sc: <http://schema.org/>
"""

# select and construct queries
def run_query(queryString,verbose = True):
    to_run = prefixString + "\n" + queryString

    sparql = SPARQLWrapper("http://a256-gc1-03.srv.aau.dk:5820/sparql")
    sparql.setTimeout(300)
    sparql.setReturnFormat(JSON)
    sparql.setQuery(to_run)

    try :
        results = sparql.query()
        json_results = results.convert()
        if len(json_results['results']['bindings'])==0:
            print("Empty")
            return []
        array = []
        for bindings in json_results['results']['bindings']:
            app =  [ (var, value['value'])  for var, value in bindings.items() ] 
            if verbose:
                print( app)
            array.append(app)
        if verbose:
            print(len(array))
        return array

    except Exception as e :
        print("The operation failed", e)
    
# ASk queries
def run_ask_query(queryString):
    to_run = prefixString + "\n" + queryString

    sparql = SPARQLWrapper("http://a256-gc1-03.srv.aau.dk:5820/sparql")
    sparql.setTimeout(300)
    sparql.setReturnFormat(JSON)
    sparql.setQuery(to_run)

    try :
        return sparql.query().convert()

    except Exception as e :
        print("The operation failed", e)

# %% [markdown]
# # Sport Workflow Series (Tennis explorative search")
#
# Consider the following exploratory information need:
#
# > investigate tennis and find the main BGPs related to this sport. Compare players per countries, awards of the players and tournament.

# %% [markdown]
# ## Useful URIs for the current workflow
# The following are given:
#
# | IRI           | Description   | Role      |
# | -----------   | -----------   |-----------|
# | `wdt:P1647`   | subproperty   | predicate |
# | `wdt:P31`     | instance of   | predicate |
# | `wdt:P106`    | profession    | predicate |
# | `wdt:P279`    | subclass      | predicate |
# | `wdt:P27`     | nationality   | predicate |
# | `wd:Q5`| Human       | node |
# | `wd:Q1426`| Roger Federer       | node |
# | `wd:Q11459`| Serena Williams       | node |

# %% [markdown]
# Also consider
#
# ```
# wd:Q1426 ?p ?obj .
# ```
#
# is the BGP to retrieve all **properties of Roger Federer**
#
# Please consider that when you return a resource, you should return the IRI and the label of the resource. In particular, when the task require you to identify a BGP the result set must always be a list of couples IRI - label.
#
#
#
# The workload should:
#
#
# 1. Identify the BGP for tennis player
#
# 2. Identify the BGP for tennis tournament
#
# 3. Return the four Grand Slam of tennis (hint: One of these four is Wimbledon) (the result set must be a list of four couples Grand Slam IRI and label).
#
# 4. Find the three different type of possible surfaces in a tennis court (the result set must be a list of three couples surface IRI and label).
#
# 5. Return the tournaments played in the 2018 Wimbledon Championships edition with the related winners (hint: men and women do not play together, there are two distinct tournament ) (the result set must be a list of elements with tournament IRI and label, and winner IRI and label).
#
# 6. Consider the tennis players born after 1975, return who won more Grand Slams and cut the result to the top-10 (the result set must be a list of triples player IRI, label and #victories).
#
# 7. Consider the country for sport property of the tennis player (NO Country of citizenship). Return the countries with at least one player who won at least one edition of each Grand Slam (the result set must be a list of country IRI and label).
#
# 8. Consider the country for sport property of the tennis player (NO Country of citizenship). Return the countries with at least one player who was ranked 1 in the tennis ranking  (the result set must be a list of country IRI and label).

# %% [markdown]
# ## Task 1
# Identify the BGP for tennis player

# %%
# write your queries
# getting object/data properties of node 'Roger Federer'
queryString = """
SELECT DISTINCT ?property ?label
WHERE
{
   wd:Q1426 ?property ?object.
   
   # ?property sc:name ?label.
}
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('property', 'http://www.wikidata.org/prop/direct/P1006'), ('label', 'Nationale Thesaurus voor Auteurs ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P103'), ('label', 'native language')]
# [('property', 'http://www.wikidata.org/prop/direct/P106'), ('label', 'occupation')]
# [('property', 'http://www.wikidata.org/prop/direct/P108'), ('label', 'employer')]
# [('property', 'http://www.wikidata.org/prop/direct/P1263'), ('label', 'NNDB people ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1280'), ('label', 'CONOR.SI ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1284'), ('label', 'Munzinger person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1285'), ('label', 'Munzinger Sport number')]
# [('property', 'http://www.wikidata.org/prop/direct/P1296'), ('label', 'Gran Enciclopèdia Catalana ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1343'), ('label', 'described by source')]
# [('property', 'http://www.wikidata.org/prop/direct/P1344'), ('label', 'participant in')]
# [('property', 'http://www.wikidata.org/prop/direct/P1352'), ('label', 'ranking')]
# [('property', 'http://www.wikidata.org/prop/direct/P140'), ('label', 'religion')]
# [('property', 'http://www.wikidata.org/prop/direct/P1412'), ('label', 'languages spoken, written or signed')]
# [('property', 'http://www.wikidata.org/prop/direct/P1417'), ('label', 'Encyclopædia Britannica Online ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1447'), ('label', 'Sports-Reference.com Olympic athlete ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1532'), ('label', 'country for sport')]
# [('property', 'http://www.wikidata.org/prop/direct/P166'), ('label', 'award received')]
# [('property', 'http://www.wikidata.org/prop/direct/P1695'), ('label', 'NLP ID (unique)')]
# [('property', 'http://www.wikidata.org/prop/direct/P1741'), ('label', 'GTAA ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P18'), ('label', 'image')]
# [('property', 'http://www.wikidata.org/prop/direct/P19'), ('label', 'place of birth')]
# [('property', 'http://www.wikidata.org/prop/direct/P2002'), ('label', 'Twitter username')]
# [('property', 'http://www.wikidata.org/prop/direct/P2003'), ('label', 'Instagram username')]
# [('property', 'http://www.wikidata.org/prop/direct/P2013'), ('label', 'Facebook ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2019'), ('label', 'AllMovie person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2031'), ('label', 'work period (start)')]
# [('property', 'http://www.wikidata.org/prop/direct/P2048'), ('label', 'height')]
# [('property', 'http://www.wikidata.org/prop/direct/P2067'), ('label', 'mass')]
# [('property', 'http://www.wikidata.org/prop/direct/P21'), ('label', 'sex or gender')]
# [('property', 'http://www.wikidata.org/prop/direct/P2121'), ('label', 'prize money')]
# [('property', 'http://www.wikidata.org/prop/direct/P213'), ('label', 'ISNI')]
# [('property', 'http://www.wikidata.org/prop/direct/P214'), ('label', 'VIAF ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2163'), ('label', 'FAST ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P22'), ('label', 'father')]
# [('property', 'http://www.wikidata.org/prop/direct/P2218'), ('label', 'net worth')]
# [('property', 'http://www.wikidata.org/prop/direct/P227'), ('label', 'GND ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2416'), ('label', 'sports discipline competed in')]
# [('property', 'http://www.wikidata.org/prop/direct/P244'), ('label', 'Library of Congress authority ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P25'), ('label', 'mother')]
# [('property', 'http://www.wikidata.org/prop/direct/P2522'), ('label', 'victory')]
# [('property', 'http://www.wikidata.org/prop/direct/P26'), ('label', 'spouse')]
# [('property', 'http://www.wikidata.org/prop/direct/P2604'), ('label', 'Kinopoisk person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2605'), ('label', 'ČSFD person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P268'), ('label', 'Bibliothèque nationale de France ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P269'), ('label', 'IdRef ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P27'), ('label', 'country of citizenship')]
# [('property', 'http://www.wikidata.org/prop/direct/P286'), ('label', 'head coach')]
# [('property', 'http://www.wikidata.org/prop/direct/P2924'), ('label', 'Great Russian Encyclopedia Online ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P31'), ('label', 'instance of')]
# [('property', 'http://www.wikidata.org/prop/direct/P3171'), ('label', 'Olympic.org athlete ID (archived version)')]
# [('property', 'http://www.wikidata.org/prop/direct/P3219'), ('label', 'Encyclopædia Universalis ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3221'), ('label', 'New York Times topic ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3222'), ('label', 'NE.se ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3342'), ('label', 'significant person')]
# [('property', 'http://www.wikidata.org/prop/direct/P3373'), ('label', 'sibling')]
# [('property', 'http://www.wikidata.org/prop/direct/P3388'), ('label', 'LittleSis people ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3417'), ('label', 'Quora topic ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3427'), ('label', 'AS.com athlete ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P345'), ('label', 'IMDb ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3509'), ('label', 'Dagens Nyheter topic ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3553'), ('label', 'Zhihu topic ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3630'), ('label', 'Babelio author ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P373'), ('label', 'Commons category')]
# [('property', 'http://www.wikidata.org/prop/direct/P3846'), ('label', 'DBC author ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P39'), ('label', 'position held')]
# [('property', 'http://www.wikidata.org/prop/direct/P40'), ('label', 'child')]
# [('property', 'http://www.wikidata.org/prop/direct/P4342'), ('label', 'Store norske leksikon ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4544'), ('label', 'Tennis Temple player ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P463'), ('label', 'member of')]
# [('property', 'http://www.wikidata.org/prop/direct/P4666'), ('label', 'CineMagia person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4789'), ('label', "Who's Who UK ID")]
# [('property', 'http://www.wikidata.org/prop/direct/P4985'), ('label', 'TMDb person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5019'), ('label', 'Brockhaus Enzyklopädie online ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5034'), ('label', 'National Library of Korea ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5247'), ('label', 'Giant Bomb ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5337'), ('label', 'Google News topics ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5361'), ('label', 'BNB person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P5421'), ('label', 'Trading Card Database person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P551'), ('label', 'residence')]
# [('property', 'http://www.wikidata.org/prop/direct/P552'), ('label', 'handedness')]
# [('property', 'http://www.wikidata.org/prop/direct/P555'), ('label', 'doubles record')]
# [('property', 'http://www.wikidata.org/prop/direct/P5617'), ('label', 'Evene ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P564'), ('label', 'singles record')]
# [('property', 'http://www.wikidata.org/prop/direct/P569'), ('label', 'date of birth')]
# [('property', 'http://www.wikidata.org/prop/direct/P5815'), ('label', 'Olympics.com athlete ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P599'), ('label', 'ITF player ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6262'), ('label', 'Fandom article ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6327'), ('label', 'Goodreads character ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P641'), ('label', 'sport')]
# [('property', 'http://www.wikidata.org/prop/direct/P646'), ('label', 'Freebase ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6553'), ('label', 'personal pronoun')]
# [('property', 'http://www.wikidata.org/prop/direct/P6573'), ('label', 'Klexikon article ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6656'), ('label', 'BHCL ID (former scheme)')]
# [('property', 'http://www.wikidata.org/prop/direct/P6683'), ('label', 'Alexander Turnbull Library ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6868'), ('label', 'Hoopla artist ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P691'), ('label', 'NKCR AUT ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7293'), ('label', 'PLWABN ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P734'), ('label', 'family name')]
# [('property', 'http://www.wikidata.org/prop/direct/P735'), ('label', 'given name')]
# [('property', 'http://www.wikidata.org/prop/direct/P741'), ('label', 'playing hand')]
# [('property', 'http://www.wikidata.org/prop/direct/P7818'), ('label', 'French Vikidia ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7859'), ('label', 'WorldCat Identities ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7929'), ('label', 'Roglo person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7982'), ('label', 'Hrvatska enciklopedija ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P8286'), ('label', 'Olympedia people ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P856'), ('label', 'official website')]
# [('property', 'http://www.wikidata.org/prop/direct/P8618'), ('label', 'ITF player ID 2020')]
# [('property', 'http://www.wikidata.org/prop/direct/P8672'), ('label', 'Twitter topic ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P8687'), ('label', 'social media followers')]
# [('property', 'http://www.wikidata.org/prop/direct/P9037'), ('label', 'BHCL UUID')]
# [('property', 'http://www.wikidata.org/prop/direct/P910'), ('label', "topic's main category")]
# [('property', 'http://www.wikidata.org/prop/direct/P9322'), ('label', 'SVKKL authority ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P949'), ('label', 'National Library of Israel ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P950'), ('label', 'Biblioteca Nacional de España ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P9743'), ('label', 'Podchaser creator ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2641'), ('label', 'Davis Cup player ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P536'), ('label', 'ATP player ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6758'), ('label', 'supported sports team')]
# [('property', 'http://www.wikidata.org/prop/direct/P4503'), ('label', 'Wimbledon player ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6308'), ('label', 'Scoresway tennis person ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6215'), ('label', 'Vesti.kz person ID')]
# 122

# %%
# checking 'occupation' property of node 'Roger Federer'
queryString = """
SELECT ?object ?label
WHERE
{
   wd:Q1426 wdt:P106 ?object.
   
   # ?object sc:name ?label.
}
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('object', 'http://www.wikidata.org/entity/Q10833314'), ('label', 'tennis player')]
# 1

# %% [markdown]
# Final query for this task

# %%
# write your final query
queryString = """
SELECT ?object ?label
WHERE
{
   wd:Q1426 wdt:P106 ?object.
   
   # ?object sc:name ?label.
}
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('object', 'http://www.wikidata.org/entity/Q10833314'), ('label', 'tennis player')]
# 1

# %% [markdown]
# ## Task 2
# Identify the BGP for tennis tournament

# %%
# write your queries
# checking 'participant in' property of node 'Roger Federer'
queryString = """
SELECT ?object ?label
WHERE
{
   wd:Q1426 wdt:P1344 ?object.
   
   # ?object sc:name ?label.
}
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('object', 'http://www.wikidata.org/entity/Q589310'), ('label', "tennis at the 2000 Summer Olympics – men's singles")]
# [('object', 'http://www.wikidata.org/entity/Q8544'), ('label', '2000 Summer Olympics')]
# [('object', 'http://www.wikidata.org/entity/Q8558'), ('label', '2004 Summer Olympics')]
# [('object', 'http://www.wikidata.org/entity/Q581788'), ('label', "tennis at the 2012 Summer Olympics – men's singles")]
# [('object', 'http://www.wikidata.org/entity/Q757054'), ('label', "tennis at the 2008 Summer Olympics – men's doubles")]
# 5

# %%
# getting object/data properties of node 'Q589310' retrieved from last query output
queryString = """
SELECT ?object ?label
WHERE
{
   wd:Q589310 wdt:P31 ?object.
   
   # ?object sc:name ?label.
}
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('object', 'http://www.wikidata.org/entity/Q18536594'), ('label', 'Olympic sporting event')]
# [('object', 'http://www.wikidata.org/entity/Q46190676'), ('label', 'tennis event')]
# 2

# %%
# getting object/data properties of node 'tennis event'
queryString = """
SELECT DISTINCT ?property ?label
WHERE
{
   wd:Q46190676 ?property ?object.
   
   # ?property sc:name ?label.
}
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('property', 'http://www.wikidata.org/prop/direct/P1424'), ('label', "topic's main template")]
# [('property', 'http://www.wikidata.org/prop/direct/P1552'), ('label', 'has quality')]
# [('property', 'http://www.wikidata.org/prop/direct/P1963'), ('label', 'properties for this type')]
# [('property', 'http://www.wikidata.org/prop/direct/P2670'), ('label', 'has parts of the class')]
# [('property', 'http://www.wikidata.org/prop/direct/P279'), ('label', 'subclass of')]
# [('property', 'http://www.wikidata.org/prop/direct/P361'), ('label', 'part of')]
# [('property', 'http://www.wikidata.org/prop/direct/P641'), ('label', 'sport')]
# 7

# %%
# s:'tennis event' p:'part of' o:what node?
queryString = """
SELECT ?object ?label
WHERE
{
   wd:Q46190676 wdt:P361 ?object.
   
   # ?object sc:name ?label.
}
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('object', 'http://www.wikidata.org/entity/Q47345468'), ('label', 'tennis tournament edition')]
# 1

# %%
# getting object/data properties of node 'tennis tournament edition' 
queryString = """
SELECT DISTINCT ?property ?label
WHERE
{
   wd:Q47345468 ?property ?object.
   
   # ?property sc:name ?label.
}
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('property', 'http://www.wikidata.org/prop/direct/P1424'), ('label', "topic's main template")]
# [('property', 'http://www.wikidata.org/prop/direct/P1963'), ('label', 'properties for this type')]
# [('property', 'http://www.wikidata.org/prop/direct/P2670'), ('label', 'has parts of the class')]
# [('property', 'http://www.wikidata.org/prop/direct/P279'), ('label', 'subclass of')]
# [('property', 'http://www.wikidata.org/prop/direct/P361'), ('label', 'part of')]
# [('property', 'http://www.wikidata.org/prop/direct/P641'), ('label', 'sport')]
# [('property', 'http://www.wikidata.org/prop/direct/P8408'), ('label', 'KBpedia ID')]
# 7

# %%
# s:'tennis tournament edition' p:'part of' o:what node?
queryString = """
SELECT ?object ?label
WHERE
{
   wd:Q47345468 wdt:P361 ?object.
   
   # ?object sc:name ?label.
}
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('object', 'http://www.wikidata.org/entity/Q13219666'), ('label', 'tennis tournament')]
# [('object', 'http://www.wikidata.org/entity/Q47358534'), ('label', 'tennis tour edition')]
# 2

# %% [markdown]
# Final query for this task

# %%
# write your final query
queryString = """
SELECT ?object ?label
WHERE
{
   wd:Q1426 wdt:P1344 wd:Q589310.
   wd:Q589310 wdt:P31 wd:Q46190676.
   wd:Q46190676 wdt:P361 wd:Q47345468.
   wd:Q47345468 wdt:P361 ?object.
   
   # ?object sc:name ?label.
}
LIMIT 1
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('object', 'http://www.wikidata.org/entity/Q13219666'), ('label', 'tennis tournament')]
# 1

# %% [markdown]
# ## Task 3
# Return the four Grand Slam of tennis (hint: One of these four is Wimbledon) (the result set must be a list of four couples Grand Slam IRI and label).

# %%
# write your queries
# checking the 'victory' property of node 'Roger Federer'
queryString = """
SELECT ?object ?label
WHERE
{
   wd:Q1426 wdt:P2522 ?object.
   
   # ?object sc:name ?label.
}
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('object', 'http://www.wikidata.org/entity/Q22956224'), ('label', "2017 Australian Open – Men's Singles")]
# [('object', 'http://www.wikidata.org/entity/Q612597'), ('label', '2007 Tennis Masters Cup')]
# [('object', 'http://www.wikidata.org/entity/Q782589'), ('label', "2010 Australian Open – Men's Singles")]
# [('object', 'http://www.wikidata.org/entity/Q782420'), ('label', "2006 Australian Open – Men's Singles")]
# [('object', 'http://www.wikidata.org/entity/Q300024'), ('label', '2011 ATP World Tour Finals')]
# [('object', 'http://www.wikidata.org/entity/Q753300'), ('label', "2012 Wimbledon Championships – Gentlemen's Singles")]
# [('object', 'http://www.wikidata.org/entity/Q757054'), ('label', "tennis at the 2008 Summer Olympics – men's doubles")]
# [('object', 'http://www.wikidata.org/entity/Q1074654'), ('label', "2006 Wimbledon Championships – Men's Singles")]
# [('object', 'http://www.wikidata.org/entity/Q384929'), ('label', "2005 Wimbledon Championships – Men's Singles")]
# [('object', 'http://www.wikidata.org/entity/Q14916861'), ('label', '2014 Davis Cup')]
# [('object', 'http://www.wikidata.org/entity/Q46993124'), ('label', "2018 Australian Open – Men's Singles")]
# [('object', 'http://www.wikidata.org/entity/Q964291'), ('label', '2006 Tennis Masters Cup')]
# [('object', 'http://www.wikidata.org/entity/Q300022'), ('label', '2010 ATP World Tour Finals')]
# [('object', 'http://www.wikidata.org/entity/Q1048953'), ('label', "2004 US Open – Men's Singles")]
# [('object', 'http://www.wikidata.org/entity/Q731509'), ('label', "2005 US Open – Men's Singles")]
# [('object', 'http://www.wikidata.org/entity/Q741573'), ('label', "2009 French Open – Men's Singles")]
# [('object', 'http://www.wikidata.org/entity/Q912506'), ('label', "2006 US Open – Men's Singles")]
# [('object', 'http://www.wikidata.org/entity/Q248965'), ('label', "2004 Wimbledon Championships – Men's Singles")]
# [('object', 'http://www.wikidata.org/entity/Q378627'), ('label', "2003 Wimbledon Championships – Men's Singles")]
# [('object', 'http://www.wikidata.org/entity/Q779654'), ('label', "2004 Australian Open - men's singles")]
# [('object', 'http://www.wikidata.org/entity/Q25344123'), ('label', "2017 Wimbledon Championships – Men's Singles")]
# [('object', 'http://www.wikidata.org/entity/Q2478340'), ('label', '2011 BNP Paribas Masters – singles')]
# [('object', 'http://www.wikidata.org/entity/Q751798'), ('label', "2009 Wimbledon Championships – Men's Singles")]
# [('object', 'http://www.wikidata.org/entity/Q782451'), ('label', "2007 Australian Open – Men's Singles")]
# [('object', 'http://www.wikidata.org/entity/Q912483'), ('label', "2007 Wimbledon Championships – Men's Singles")]
# [('object', 'http://www.wikidata.org/entity/Q304072'), ('label', "2008 US Open – Men's Singles")]
# [('object', 'http://www.wikidata.org/entity/Q2031910'), ('label', '2003 Tennis Masters Cup')]
# [('object', 'http://www.wikidata.org/entity/Q2094307'), ('label', '2004 Tennis Masters Cup')]
# [('object', 'http://www.wikidata.org/entity/Q836815'), ('label', "2007 US Open – Men's Singles")]
# 29

# %%
# getting object/data properties of node '2012 wimbledon championships – gentlemen's singles' 
queryString = """
SELECT DISTINCT ?property ?label
WHERE
{
   wd:Q753300 ?property ?object.
   
   # ?property sc:name ?label.
}
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('property', 'http://www.wikidata.org/prop/direct/P1346'), ('label', 'winner')]
# [('property', 'http://www.wikidata.org/prop/direct/P17'), ('label', 'country')]
# [('property', 'http://www.wikidata.org/prop/direct/P2094'), ('label', 'competition class')]
# [('property', 'http://www.wikidata.org/prop/direct/P31'), ('label', 'instance of')]
# [('property', 'http://www.wikidata.org/prop/direct/P361'), ('label', 'part of')]
# [('property', 'http://www.wikidata.org/prop/direct/P585'), ('label', 'point in time')]
# [('property', 'http://www.wikidata.org/prop/direct/P641'), ('label', 'sport')]
# [('property', 'http://www.wikidata.org/prop/direct/P646'), ('label', 'Freebase ID')]
# 8

# %%
# checking the 'part of' property of node '2012 wimbledon championships – gentlemen's singles'
queryString = """
SELECT ?object ?label
WHERE
{
   wd:Q753300 wdt:P361 ?object.
   
   # ?object sc:name ?label.
}
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('object', 'http://www.wikidata.org/entity/Q289587'), ('label', '2012 Wimbledon Championships')]
# 1

# %%
# getting object/data properties of node '2012 wimbledon championships'
queryString = """
SELECT DISTINCT ?property ?label
WHERE
{
   wd:Q289587 ?property ?object.
   
   # ?property sc:name ?label.
}
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('property', 'http://www.wikidata.org/prop/direct/P6880'), ('label', 'ATP tennis tournament edition ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P155'), ('label', 'follows')]
# [('property', 'http://www.wikidata.org/prop/direct/P156'), ('label', 'followed by')]
# [('property', 'http://www.wikidata.org/prop/direct/P17'), ('label', 'country')]
# [('property', 'http://www.wikidata.org/prop/direct/P18'), ('label', 'image')]
# [('property', 'http://www.wikidata.org/prop/direct/P2581'), ('label', 'BabelNet ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P31'), ('label', 'instance of')]
# [('property', 'http://www.wikidata.org/prop/direct/P373'), ('label', 'Commons category')]
# [('property', 'http://www.wikidata.org/prop/direct/P393'), ('label', 'edition number')]
# [('property', 'http://www.wikidata.org/prop/direct/P527'), ('label', 'has part')]
# [('property', 'http://www.wikidata.org/prop/direct/P580'), ('label', 'start time')]
# [('property', 'http://www.wikidata.org/prop/direct/P582'), ('label', 'end time')]
# [('property', 'http://www.wikidata.org/prop/direct/P585'), ('label', 'point in time')]
# [('property', 'http://www.wikidata.org/prop/direct/P641'), ('label', 'sport')]
# [('property', 'http://www.wikidata.org/prop/direct/P646'), ('label', 'Freebase ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P856'), ('label', 'official website')]
# [('property', 'http://www.wikidata.org/prop/direct/P910'), ('label', "topic's main category")]
# 17

# %%
# checking the 'instance of' property of node '2012 wimbledon championships'
queryString = """
SELECT ?object ?label
WHERE
{
   wd:Q289587 wdt:P31 ?object.
   
   # ?object sc:name ?label.
}
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('object', 'http://www.wikidata.org/entity/Q47345468'), ('label', 'tennis tournament edition')]
# [('object', 'http://www.wikidata.org/entity/Q41520'), ('label', 'Wimbledon Championships')]
# 2

# %%
# getting object/data properties of node 'wimbledon championships'
queryString = """
SELECT DISTINCT ?property ?label
WHERE
{
   wd:Q41520 ?property ?object.
   
   # ?property sc:name ?label.
}
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('property', 'http://www.wikidata.org/prop/direct/P131'), ('label', 'located in the administrative territorial entity')]
# [('property', 'http://www.wikidata.org/prop/direct/P1417'), ('label', 'Encyclopædia Britannica Online ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1424'), ('label', "topic's main template")]
# [('property', 'http://www.wikidata.org/prop/direct/P1687'), ('label', 'Wikidata property')]
# [('property', 'http://www.wikidata.org/prop/direct/P17'), ('label', 'country')]
# [('property', 'http://www.wikidata.org/prop/direct/P18'), ('label', 'image')]
# [('property', 'http://www.wikidata.org/prop/direct/P1889'), ('label', 'different from')]
# [('property', 'http://www.wikidata.org/prop/direct/P2002'), ('label', 'Twitter username')]
# [('property', 'http://www.wikidata.org/prop/direct/P2003'), ('label', 'Instagram username')]
# [('property', 'http://www.wikidata.org/prop/direct/P2013'), ('label', 'Facebook ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P214'), ('label', 'VIAF ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2257'), ('label', 'event interval')]
# [('property', 'http://www.wikidata.org/prop/direct/P227'), ('label', 'GND ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2354'), ('label', 'has list')]
# [('property', 'http://www.wikidata.org/prop/direct/P2397'), ('label', 'YouTube channel ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P244'), ('label', 'Library of Congress authority ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P276'), ('label', 'location')]
# [('property', 'http://www.wikidata.org/prop/direct/P279'), ('label', 'subclass of')]
# [('property', 'http://www.wikidata.org/prop/direct/P2924'), ('label', 'Great Russian Encyclopedia Online ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P31'), ('label', 'instance of')]
# [('property', 'http://www.wikidata.org/prop/direct/P3221'), ('label', 'New York Times topic ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3417'), ('label', 'Quora topic ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3479'), ('label', 'Omni topic ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P361'), ('label', 'part of')]
# [('property', 'http://www.wikidata.org/prop/direct/P373'), ('label', 'Commons category')]
# [('property', 'http://www.wikidata.org/prop/direct/P4431'), ('label', 'Google Doodle')]
# [('property', 'http://www.wikidata.org/prop/direct/P4622'), ('label', 'trophy awarded')]
# [('property', 'http://www.wikidata.org/prop/direct/P571'), ('label', 'inception')]
# [('property', 'http://www.wikidata.org/prop/direct/P641'), ('label', 'sport')]
# [('property', 'http://www.wikidata.org/prop/direct/P646'), ('label', 'Freebase ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P664'), ('label', 'organizer')]
# [('property', 'http://www.wikidata.org/prop/direct/P691'), ('label', 'NKCR AUT ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P765'), ('label', 'surface played on')]
# [('property', 'http://www.wikidata.org/prop/direct/P7818'), ('label', 'French Vikidia ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7859'), ('label', 'WorldCat Identities ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P7959'), ('label', 'historic county')]
# [('property', 'http://www.wikidata.org/prop/direct/P856'), ('label', 'official website')]
# [('property', 'http://www.wikidata.org/prop/direct/P8687'), ('label', 'social media followers')]
# [('property', 'http://www.wikidata.org/prop/direct/P910'), ('label', "topic's main category")]
# [('property', 'http://www.wikidata.org/prop/direct/P948'), ('label', 'page banner')]
# 40

# %%
# checking the 'part of' property of node 'wimbledon championships'
queryString = """
SELECT ?object ?label
WHERE
{
   wd:Q41520 wdt:P361 ?object.
   
   # ?object sc:name ?label.
}
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('object', 'http://www.wikidata.org/entity/Q102113'), ('label', 'Grand Slam of tennis')]
# 1

# %%
# getting object/data properties of node 'grand slam of tennis'
queryString = """
SELECT DISTINCT ?property ?label
WHERE
{
   wd:Q102113 ?property ?object.
   
   # ?property sc:name ?label.
}
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('property', 'http://www.wikidata.org/prop/direct/P1417'), ('label', 'Encyclopædia Britannica Online ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1424'), ('label', "topic's main template")]
# [('property', 'http://www.wikidata.org/prop/direct/P18'), ('label', 'image')]
# [('property', 'http://www.wikidata.org/prop/direct/P2354'), ('label', 'has list')]
# [('property', 'http://www.wikidata.org/prop/direct/P279'), ('label', 'subclass of')]
# [('property', 'http://www.wikidata.org/prop/direct/P2924'), ('label', 'Great Russian Encyclopedia Online ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P31'), ('label', 'instance of')]
# [('property', 'http://www.wikidata.org/prop/direct/P3222'), ('label', 'NE.se ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3417'), ('label', 'Quora topic ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P373'), ('label', 'Commons category')]
# [('property', 'http://www.wikidata.org/prop/direct/P527'), ('label', 'has part')]
# [('property', 'http://www.wikidata.org/prop/direct/P641'), ('label', 'sport')]
# [('property', 'http://www.wikidata.org/prop/direct/P646'), ('label', 'Freebase ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P8408'), ('label', 'KBpedia ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P910'), ('label', "topic's main category")]
# 15

# %%
# checking the 'has list' property of node 'grand slam of tennis'
queryString = """
SELECT ?object ?label
WHERE
{
   wd:Q102113 wdt:P2354 ?object.
   
   # ?object sc:name ?label.
}
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('object', 'http://www.wikidata.org/entity/Q1426439'), ('label', "list of Grand Slam men's singles champions")]
# [('object', 'http://www.wikidata.org/entity/Q645455'), ('label', "list of Grand Slam women's singles champions")]
# 2

# %%
# checking the 'has part' property of node 'grand slam of tennis'

# one of the outputs is 'french cheese' instead of being 'french open' which is a weird problem! 
# so I checked wikidata online and the instance is correctly written as 'french open' on there
queryString = """
SELECT ?object ?label
WHERE
{
   wd:Q102113 wdt:P527 ?object.
   
   # ?object sc:name ?label.
}
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('object', 'http://www.wikidata.org/entity/Q2223649'), ('label', 'French cheese')]
# [('object', 'http://www.wikidata.org/entity/Q123577'), ('label', 'US Open')]
# [('object', 'http://www.wikidata.org/entity/Q41520'), ('label', 'Wimbledon Championships')]
# [('object', 'http://www.wikidata.org/entity/Q60874'), ('label', 'Australian Open')]
# 4

# %% [markdown]
# Final query for this task

# %%
# write your final query
# takes around 4/5 minutes to output the result
 
# the output being 'french cheese' will probably affect the results of the other tasks!
queryString = """
SELECT ?grand_slam_iri ?label
WHERE
{
   wd:Q1426 wdt:P2522 wd:Q753300.
   wd:Q753300 wdt:P361 wd:Q289587.
   wd:Q289587 wdt:P31 wd:Q41520.
   wd:Q41520 wdt:P361 wd:Q102113.
   wd:Q102113 wdt:P527 ?grand_slam_iri.
   
   # ?grand_slam_iri sc:name ?label.
}
"""

print("Results")
x=run_query(queryString)

# %% [markdown]
# ## Task 4
# Find the three different type of possible surfaces in a tennis court (the result set must be a list of three couples surface IRI and label).

# %%
# write your queries
# checking 'occupation' property of node 'Roger Federer'
queryString = """
SELECT ?object ?label
WHERE
{
   wd:Q1426 wdt:P106 ?object.
   
   # ?object sc:name ?label.
}
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('object', 'http://www.wikidata.org/entity/Q10833314'), ('label', 'tennis player')]
# 1

# %%
# getting object/data properties of node 'tennis player'
queryString = """
SELECT DISTINCT ?property ?label
WHERE
{
   wd:Q10833314 ?property ?object.
   
   # ?property sc:name ?label.
}
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('property', 'http://www.wikidata.org/prop/direct/P1014'), ('label', 'Art & Architecture Thesaurus ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1296'), ('label', 'Gran Enciclopèdia Catalana ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1424'), ('label', "topic's main template")]
# [('property', 'http://www.wikidata.org/prop/direct/P1552'), ('label', 'has quality')]
# [('property', 'http://www.wikidata.org/prop/direct/P1709'), ('label', 'equivalent class')]
# [('property', 'http://www.wikidata.org/prop/direct/P18'), ('label', 'image')]
# [('property', 'http://www.wikidata.org/prop/direct/P1963'), ('label', 'properties for this type')]
# [('property', 'http://www.wikidata.org/prop/direct/P227'), ('label', 'GND ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2354'), ('label', 'has list')]
# [('property', 'http://www.wikidata.org/prop/direct/P244'), ('label', 'Library of Congress authority ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P268'), ('label', 'Bibliothèque nationale de France ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P279'), ('label', 'subclass of')]
# [('property', 'http://www.wikidata.org/prop/direct/P2888'), ('label', 'exact match')]
# [('property', 'http://www.wikidata.org/prop/direct/P31'), ('label', 'instance of')]
# [('property', 'http://www.wikidata.org/prop/direct/P3417'), ('label', 'Quora topic ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P373'), ('label', 'Commons category')]
# [('property', 'http://www.wikidata.org/prop/direct/P425'), ('label', 'field of this occupation')]
# [('property', 'http://www.wikidata.org/prop/direct/P508'), ('label', 'BNCF Thesaurus ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P6186'), ('label', 'category for eponymous categories')]
# [('property', 'http://www.wikidata.org/prop/direct/P641'), ('label', 'sport')]
# [('property', 'http://www.wikidata.org/prop/direct/P646'), ('label', 'Freebase ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P8814'), ('label', 'WordNet 3.1 Synset ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P910'), ('label', "topic's main category")]
# 23

# %%
# checking 'sport' property of node 'tennis player'
queryString = """
SELECT ?object ?label
WHERE
{
   wd:Q10833314 wdt:P641 ?object.
   
   # ?object sc:name ?label.
}
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('object', 'http://www.wikidata.org/entity/Q847'), ('label', 'tennis')]
# 1

# %%
# getting object/data properties of node 'tennis'
queryString = """
SELECT DISTINCT ?property ?label
WHERE
{
   wd:Q847 ?property ?object.
   
   # ?property sc:name ?label.
}
LIMIT 50
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('property', 'http://www.wikidata.org/prop/direct/P1014'), ('label', 'Art & Architecture Thesaurus ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1051'), ('label', 'PSH ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1151'), ('label', "topic's main Wikimedia portal")]
# [('property', 'http://www.wikidata.org/prop/direct/P1225'), ('label', 'U.S. National Archives Identifier')]
# [('property', 'http://www.wikidata.org/prop/direct/P1245'), ('label', 'OmegaWiki Defined Meaning')]
# [('property', 'http://www.wikidata.org/prop/direct/P1256'), ('label', 'Iconclass notation')]
# [('property', 'http://www.wikidata.org/prop/direct/P1282'), ('label', 'OpenStreetMap tag or key')]
# [('property', 'http://www.wikidata.org/prop/direct/P1296'), ('label', 'Gran Enciclopèdia Catalana ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1343'), ('label', 'described by source')]
# [('property', 'http://www.wikidata.org/prop/direct/P1417'), ('label', 'Encyclopædia Britannica Online ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1424'), ('label', "topic's main template")]
# [('property', 'http://www.wikidata.org/prop/direct/P18'), ('label', 'image')]
# [('property', 'http://www.wikidata.org/prop/direct/P1807'), ('label', 'Great Aragonese Encyclopedia ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P1873'), ('label', 'maximum number of players')]
# [('property', 'http://www.wikidata.org/prop/direct/P1889'), ('label', 'different from')]
# [('property', 'http://www.wikidata.org/prop/direct/P2184'), ('label', 'history of topic')]
# [('property', 'http://www.wikidata.org/prop/direct/P227'), ('label', 'GND ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2283'), ('label', 'uses')]
# [('property', 'http://www.wikidata.org/prop/direct/P2347'), ('label', 'YSO ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P244'), ('label', 'Library of Congress authority ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P268'), ('label', 'Bibliothèque nationale de France ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P279'), ('label', 'subclass of')]
# [('property', 'http://www.wikidata.org/prop/direct/P2888'), ('label', 'exact match')]
# [('property', 'http://www.wikidata.org/prop/direct/P2910'), ('label', 'icon')]
# [('property', 'http://www.wikidata.org/prop/direct/P2924'), ('label', 'Great Russian Encyclopedia Online ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3095'), ('label', 'practiced by')]
# [('property', 'http://www.wikidata.org/prop/direct/P31'), ('label', 'instance of')]
# [('property', 'http://www.wikidata.org/prop/direct/P3219'), ('label', 'Encyclopædia Universalis ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3221'), ('label', 'New York Times topic ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3222'), ('label', 'NE.se ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3417'), ('label', 'Quora topic ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P349'), ('label', 'National Diet Library ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3509'), ('label', 'Dagens Nyheter topic ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3553'), ('label', 'Zhihu topic ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P373'), ('label', 'Commons category')]
# [('property', 'http://www.wikidata.org/prop/direct/P3827'), ('label', 'JSTOR topic ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3984'), ('label', 'subreddit')]
# [('property', 'http://www.wikidata.org/prop/direct/P4073'), ('label', 'Fandom wiki ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4254'), ('label', 'Bengali Banglapedia ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4255'), ('label', 'Banglapedia (English version) ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4342'), ('label', 'Store norske leksikon ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4527'), ('label', 'UK Parliament thesaurus ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4644'), ('label', 'ESCO skill ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P4854'), ('label', 'Uppslagsverket Finland ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P486'), ('label', 'MeSH descriptor ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P487'), ('label', 'Unicode character')]
# [('property', 'http://www.wikidata.org/prop/direct/P495'), ('label', 'country of origin')]
# [('property', 'http://www.wikidata.org/prop/direct/P5008'), ('label', 'on focus list of Wikimedia project')]
# [('property', 'http://www.wikidata.org/prop/direct/P5019'), ('label', 'Brockhaus Enzyklopädie online ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P508'), ('label', 'BNCF Thesaurus ID')]
# 50

# %%
# checking 'uses' property of node 'tennis'
queryString = """
SELECT ?object ?label
WHERE
{
   wd:Q847 wdt:P2283 ?object.
   
   # ?object sc:name ?label.
}
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('object', 'http://www.wikidata.org/entity/Q153362'), ('label', 'tennis racquet')]
# [('object', 'http://www.wikidata.org/entity/Q741118'), ('label', 'tennis court')]
# [('object', 'http://www.wikidata.org/entity/Q246514'), ('label', 'tennis ball')]
# 3

# %%
# getting object/data properties of node 'tennis court'
queryString = """
SELECT DISTINCT ?property ?label
WHERE
{
   wd:Q741118 ?property ?object.
   
   # ?property sc:name ?label.
}
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('property', 'http://www.wikidata.org/prop/direct/P1225'), ('label', 'U.S. National Archives Identifier')]
# [('property', 'http://www.wikidata.org/prop/direct/P1282'), ('label', 'OpenStreetMap tag or key')]
# [('property', 'http://www.wikidata.org/prop/direct/P1535'), ('label', 'used by')]
# [('property', 'http://www.wikidata.org/prop/direct/P1552'), ('label', 'has quality')]
# [('property', 'http://www.wikidata.org/prop/direct/P18'), ('label', 'image')]
# [('property', 'http://www.wikidata.org/prop/direct/P2581'), ('label', 'BabelNet ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2670'), ('label', 'has parts of the class')]
# [('property', 'http://www.wikidata.org/prop/direct/P279'), ('label', 'subclass of')]
# [('property', 'http://www.wikidata.org/prop/direct/P3417'), ('label', 'Quora topic ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P373'), ('label', 'Commons category')]
# [('property', 'http://www.wikidata.org/prop/direct/P3827'), ('label', 'JSTOR topic ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P641'), ('label', 'sport')]
# [('property', 'http://www.wikidata.org/prop/direct/P646'), ('label', 'Freebase ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P8408'), ('label', 'KBpedia ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P8814'), ('label', 'WordNet 3.1 Synset ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P910'), ('label', "topic's main category")]
# 16

# %%
# checking 'has parts of the class' property of node 'tennis court'
queryString = """
SELECT ?object ?label
WHERE
{
   wd:Q741118 wdt:P2670 ?object.
   
   # ?object sc:name ?label.
}
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('object', 'http://www.wikidata.org/entity/Q47677460'), ('label', 'tennis playing surface')]
# [('object', 'http://www.wikidata.org/entity/Q48291351'), ('label', 'facet of tennis playing area')]
# [('object', 'http://www.wikidata.org/entity/Q4839569'), ('label', 'backboard')]
# 3

# %%
# getting object/data properties of node 'tennis playing surface'
queryString = """
SELECT DISTINCT ?property ?label
WHERE
{
   wd:Q47677460 ?property ?object.
   
   # ?property sc:name ?label.
}
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('property', 'http://www.wikidata.org/prop/direct/P1687'), ('label', 'Wikidata property')]
# [('property', 'http://www.wikidata.org/prop/direct/P2671'), ('label', 'Google Knowledge Graph ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P279'), ('label', 'subclass of')]
# [('property', 'http://www.wikidata.org/prop/direct/P361'), ('label', 'part of')]
# [('property', 'http://www.wikidata.org/prop/direct/P641'), ('label', 'sport')]
# [('property', 'http://www.wikidata.org/prop/direct/P8408'), ('label', 'KBpedia ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P910'), ('label', "topic's main category")]
# 7

# %%
# checking 'part of' property of node 'tennis playing surface'
queryString = """
SELECT ?object ?label
WHERE
{
   wd:Q47677460 wdt:P279 ?object.
   
   # ?object sc:name ?label.
}
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('object', 'http://www.wikidata.org/entity/Q28840755'), ('label', 'surface')]
# 1

# %%
# checking 'subclass of' property of node 'tennis playing surface'
queryString = """
SELECT ?object ?label
WHERE
{
   wd:Q47677460 wdt:P279 ?object.
   
   # ?object sc:name ?label.
}
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('object', 'http://www.wikidata.org/entity/Q28840755'), ('label', 'surface')]
# 1

# %%
# getting object/data properties of node 'US open' as found from last task's final query
queryString = """
SELECT DISTINCT ?property ?label
WHERE
{
   wd:Q123577 ?property ?object.
   
   # ?property sc:name ?label.
}
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('property', 'http://www.wikidata.org/prop/direct/P1417'), ('label', 'Encyclopædia Britannica Online ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P154'), ('label', 'logo image')]
# [('property', 'http://www.wikidata.org/prop/direct/P17'), ('label', 'country')]
# [('property', 'http://www.wikidata.org/prop/direct/P18'), ('label', 'image')]
# [('property', 'http://www.wikidata.org/prop/direct/P2002'), ('label', 'Twitter username')]
# [('property', 'http://www.wikidata.org/prop/direct/P2003'), ('label', 'Instagram username')]
# [('property', 'http://www.wikidata.org/prop/direct/P2013'), ('label', 'Facebook ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2121'), ('label', 'prize money')]
# [('property', 'http://www.wikidata.org/prop/direct/P214'), ('label', 'VIAF ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P2257'), ('label', 'event interval')]
# [('property', 'http://www.wikidata.org/prop/direct/P2354'), ('label', 'has list')]
# [('property', 'http://www.wikidata.org/prop/direct/P2397'), ('label', 'YouTube channel ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P244'), ('label', 'Library of Congress authority ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P276'), ('label', 'location')]
# [('property', 'http://www.wikidata.org/prop/direct/P279'), ('label', 'subclass of')]
# [('property', 'http://www.wikidata.org/prop/direct/P31'), ('label', 'instance of')]
# [('property', 'http://www.wikidata.org/prop/direct/P3221'), ('label', 'New York Times topic ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3417'), ('label', 'Quora topic ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3479'), ('label', 'Omni topic ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P3509'), ('label', 'Dagens Nyheter topic ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P361'), ('label', 'part of')]
# [('property', 'http://www.wikidata.org/prop/direct/P373'), ('label', 'Commons category')]
# [('property', 'http://www.wikidata.org/prop/direct/P4013'), ('label', 'Giphy username')]
# [('property', 'http://www.wikidata.org/prop/direct/P571'), ('label', 'inception')]
# [('property', 'http://www.wikidata.org/prop/direct/P641'), ('label', 'sport')]
# [('property', 'http://www.wikidata.org/prop/direct/P646'), ('label', 'Freebase ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P664'), ('label', 'organizer')]
# [('property', 'http://www.wikidata.org/prop/direct/P765'), ('label', 'surface played on')]
# [('property', 'http://www.wikidata.org/prop/direct/P7818'), ('label', 'French Vikidia ID')]
# [('property', 'http://www.wikidata.org/prop/direct/P856'), ('label', 'official website')]
# [('property', 'http://www.wikidata.org/prop/direct/P8687'), ('label', 'social media followers')]
# [('property', 'http://www.wikidata.org/prop/direct/P910'), ('label', "topic's main category")]
# 32

# %%
# checking 'surface played on' property of node 'US open'
queryString = """
SELECT ?object ?label
WHERE
{
   wd:Q123577 wdt:P765 ?object.
   
   # ?object sc:name ?label.
}
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('object', 'http://www.wikidata.org/entity/Q1330871'), ('label', 'hardcourt')]
# 1

# %%
# checking 'surface played on' property of node 'wimbledon championships'
queryString = """
SELECT ?object ?label
WHERE
{
   wd:Q41520 wdt:P765 ?object.
   
   # ?object sc:name ?label.
}
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('object', 'http://www.wikidata.org/entity/Q1151291'), ('label', 'grass court')]
# 1

# %% [markdown]
# Final query for this task

# %%
# write your final query

# the 'french open' grand slam has not been considered in query 
# because of the problem with task 3, that 'french cheese' does not have the property 'surface played on'
queryString = """
SELECT DISTINCT ?surface_iri ?label
WHERE
{
   wd:Q102113 wdt:P527 ?grand_slam.
   # ?grand_slam wdt:P765 ?surface_iri.
   
   # ?surface_iri sc:name ?label.
}
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('surface_iri', 'http://www.wikidata.org/entity/Q1330871'), ('label', 'hardcourt')]
# [('surface_iri', 'http://www.wikidata.org/entity/Q1151291'), ('label', 'grass court')]
# 2

# %% [markdown]
# ## Task 5
# Return the tournaments played in the 2018 Wimbledon Championships edition with the related winners (hint: men and women do not play together, there are two distinct tournament ) (the result set must be a list of elements with tournament IRI and label, and winner IRI and label).

# %%
# checking 'victory' property of node 'Roger Federer'
queryString = """
SELECT ?object ?label
WHERE
{
   wd:Q1426 wdt:P2522 ?object.
   
   # ?object sc:name ?label.
}
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('object', 'http://www.wikidata.org/entity/Q22956224'), ('label', "2017 Australian Open – Men's Singles")]
# [('object', 'http://www.wikidata.org/entity/Q612597'), ('label', '2007 Tennis Masters Cup')]
# [('object', 'http://www.wikidata.org/entity/Q782589'), ('label', "2010 Australian Open – Men's Singles")]
# [('object', 'http://www.wikidata.org/entity/Q782420'), ('label', "2006 Australian Open – Men's Singles")]
# [('object', 'http://www.wikidata.org/entity/Q300024'), ('label', '2011 ATP World Tour Finals')]
# [('object', 'http://www.wikidata.org/entity/Q753300'), ('label', "2012 Wimbledon Championships – Gentlemen's Singles")]
# [('object', 'http://www.wikidata.org/entity/Q757054'), ('label', "tennis at the 2008 Summer Olympics – men's doubles")]
# [('object', 'http://www.wikidata.org/entity/Q1074654'), ('label', "2006 Wimbledon Championships – Men's Singles")]
# [('object', 'http://www.wikidata.org/entity/Q384929'), ('label', "2005 Wimbledon Championships – Men's Singles")]
# [('object', 'http://www.wikidata.org/entity/Q14916861'), ('label', '2014 Davis Cup')]
# [('object', 'http://www.wikidata.org/entity/Q46993124'), ('label', "2018 Australian Open – Men's Singles")]
# [('object', 'http://www.wikidata.org/entity/Q964291'), ('label', '2006 Tennis Masters Cup')]
# [('object', 'http://www.wikidata.org/entity/Q300022'), ('label', '2010 ATP World Tour Finals')]
# [('object', 'http://www.wikidata.org/entity/Q1048953'), ('label', "2004 US Open – Men's Singles")]
# [('object', 'http://www.wikidata.org/entity/Q731509'), ('label', "2005 US Open – Men's Singles")]
# [('object', 'http://www.wikidata.org/entity/Q741573'), ('label', "2009 French Open – Men's Singles")]
# [('object', 'http://www.wikidata.org/entity/Q912506'), ('label', "2006 US Open – Men's Singles")]
# [('object', 'http://www.wikidata.org/entity/Q248965'), ('label', "2004 Wimbledon Championships – Men's Singles")]
# [('object', 'http://www.wikidata.org/entity/Q378627'), ('label', "2003 Wimbledon Championships – Men's Singles")]
# [('object', 'http://www.wikidata.org/entity/Q779654'), ('label', "2004 Australian Open - men's singles")]
# [('object', 'http://www.wikidata.org/entity/Q25344123'), ('label', "2017 Wimbledon Championships – Men's Singles")]
# [('object', 'http://www.wikidata.org/entity/Q2478340'), ('label', '2011 BNP Paribas Masters – singles')]
# [('object', 'http://www.wikidata.org/entity/Q751798'), ('label', "2009 Wimbledon Championships – Men's Singles")]
# [('object', 'http://www.wikidata.org/entity/Q782451'), ('label', "2007 Australian Open – Men's Singles")]
# [('object', 'http://www.wikidata.org/entity/Q912483'), ('label', "2007 Wimbledon Championships – Men's Singles")]
# [('object', 'http://www.wikidata.org/entity/Q304072'), ('label', "2008 US Open – Men's Singles")]
# [('object', 'http://www.wikidata.org/entity/Q2031910'), ('label', '2003 Tennis Masters Cup')]
# [('object', 'http://www.wikidata.org/entity/Q2094307'), ('label', '2004 Tennis Masters Cup')]
# [('object', 'http://www.wikidata.org/entity/Q836815'), ('label', "2007 US Open – Men's Singles")]
# 29

# %%
# getting object/data properties of node '2006 wimbledon championships – men's singles'
queryString = """
SELECT DISTINCT ?property ?label
WHERE
{
   wd:Q1074654 ?property ?object.
   
   # ?property sc:name ?label.
}
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('property', 'http://www.wikidata.org/prop/direct/P1346'), ('label', 'winner')]
# [('property', 'http://www.wikidata.org/prop/direct/P155'), ('label', 'follows')]
# [('property', 'http://www.wikidata.org/prop/direct/P17'), ('label', 'country')]
# [('property', 'http://www.wikidata.org/prop/direct/P2094'), ('label', 'competition class')]
# [('property', 'http://www.wikidata.org/prop/direct/P31'), ('label', 'instance of')]
# [('property', 'http://www.wikidata.org/prop/direct/P361'), ('label', 'part of')]
# [('property', 'http://www.wikidata.org/prop/direct/P585'), ('label', 'point in time')]
# [('property', 'http://www.wikidata.org/prop/direct/P641'), ('label', 'sport')]
# [('property', 'http://www.wikidata.org/prop/direct/P646'), ('label', 'Freebase ID')]
# 9

# %%
# s:what node? p:'instance of' o:'wimbledon chamiponships'
queryString = """
SELECT ?subject ?label
WHERE
{
   # ?subject wdt:P31 wd:Q41520.
   
   # ?subject sc:name ?label.
}
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('subject', 'http://www.wikidata.org/entity/Q268871'), ('label', '2004 Wimbledon Championships')]
# [('subject', 'http://www.wikidata.org/entity/Q173961'), ('label', '1978 Wimbledon Championships')]
# [('subject', 'http://www.wikidata.org/entity/Q925026'), ('label', '1971 Wimbledon Championships')]
# [('subject', 'http://www.wikidata.org/entity/Q15854765'), ('label', '2014 Wimbledon Championships')]
# [('subject', 'http://www.wikidata.org/entity/Q30085309'), ('label', '2018 Wimbledon Championships')]
# [('subject', 'http://www.wikidata.org/entity/Q745901'), ('label', '1974 Wimbledon Championships')]
# [('subject', 'http://www.wikidata.org/entity/Q655368'), ('label', '1955 Wimbledon Championships')]
# [('subject', 'http://www.wikidata.org/entity/Q655378'), ('label', '1956 Wimbledon Championships')]
# [('subject', 'http://www.wikidata.org/entity/Q657950'), ('label', '1957 Wimbledon Championships')]
# [('subject', 'http://www.wikidata.org/entity/Q657962'), ('label', '1958 Wimbledon Championships')]
# [('subject', 'http://www.wikidata.org/entity/Q2296335'), ('label', '1881 Wimbledon Championship')]
# [('subject', 'http://www.wikidata.org/entity/Q2297185'), ('label', '1882 Wimbledon Championship')]
# [('subject', 'http://www.wikidata.org/entity/Q522860'), ('label', '1883 Wimbledon Championship')]
# [('subject', 'http://www.wikidata.org/entity/Q20127632'), ('label', '2016 Wimbledon Championships')]
# [('subject', 'http://www.wikidata.org/entity/Q934978'), ('label', '1988 Wimbledon Championships')]
# [('subject', 'http://www.wikidata.org/entity/Q388312'), ('label', '2008 Wimbledon Championships')]
# [('subject', 'http://www.wikidata.org/entity/Q1049018'), ('label', '1980 Wimbledon Championships')]
# [('subject', 'http://www.wikidata.org/entity/Q404337'), ('label', '1929 Wimbledon Championships')]
# [('subject', 'http://www.wikidata.org/entity/Q404437'), ('label', '1930 Wimbledon Championships')]
# [('subject', 'http://www.wikidata.org/entity/Q404791'), ('label', '1933 Wimbledon Championships')]
# [('subject', 'http://www.wikidata.org/entity/Q855690'), ('label', '1968 Wimbledon Championships')]
# [('subject', 'http://www.wikidata.org/entity/Q577138'), ('label', '1954 Wimbledon Championships')]
# [('subject', 'http://www.wikidata.org/entity/Q244370'), ('label', '2009 Wimbledon Championships')]
# [('subject', 'http://www.wikidata.org/entity/Q18410121'), ('label', '2015 Wimbledon Championships')]
# [('subject', 'http://www.wikidata.org/entity/Q2121893'), ('label', '1903 Wimbledon Championships')]
# [('subject', 'http://www.wikidata.org/entity/Q476638'), ('label', '2010 Wimbledon Championships')]
# [('subject', 'http://www.wikidata.org/entity/Q740252'), ('label', '1976 Wimbledon Championships')]
# [('subject', 'http://www.wikidata.org/entity/Q911804'), ('label', '1969 Wimbledon Championships')]
# [('subject', 'http://www.wikidata.org/entity/Q925733'), ('label', '1970 Wimbledon Championships')]
# [('subject', 'http://www.wikidata.org/entity/Q2120586'), ('label', '1899 Wimbledon Championships')]
# [('subject', 'http://www.wikidata.org/entity/Q2120595'), ('label', '1911 Wimbledon Championships')]
# [('subject', 'http://www.wikidata.org/entity/Q501879'), ('label', '1946 Wimbledon Championships')]
# [('subject', 'http://www.wikidata.org/entity/Q2119702'), ('label', '1910 Wimbledon Championships')]
# [('subject', 'http://www.wikidata.org/entity/Q2119706'), ('label', '1898 Wimbledon Championships')]
# [('subject', 'http://www.wikidata.org/entity/Q2119719'), ('label', '1908 Wimbledon Championships')]
# [('subject', 'http://www.wikidata.org/entity/Q2119732'), ('label', '1901 Wimbledon Championships')]
# [('subject', 'http://www.wikidata.org/entity/Q2120599'), ('label', '1909 Wimbledon Championships')]
# [('subject', 'http://www.wikidata.org/entity/Q2121907'), ('label', '1900 Wimbledon Championships')]
# [('subject', 'http://www.wikidata.org/entity/Q1048601'), ('label', '1981 Wimbledon Championships')]
# [('subject', 'http://www.wikidata.org/entity/Q1281192'), ('label', '1905 Wimbledon Championships')]
# [('subject', 'http://www.wikidata.org/entity/Q1399137'), ('label', '1897 Wimbledon Championships')]
# [('subject', 'http://www.wikidata.org/entity/Q1737828'), ('label', '1890 Wimbledon Championships')]
# [('subject', 'http://www.wikidata.org/entity/Q337130'), ('label', '1927 Wimbledon Championships')]
# [('subject', 'http://www.wikidata.org/entity/Q337138'), ('label', '1928 Wimbledon Championships')]
# [('subject', 'http://www.wikidata.org/entity/Q383872'), ('label', '1985 Wimbledon Championships')]
# [('subject', 'http://www.wikidata.org/entity/Q423283'), ('label', '1935 Wimbledon Championships')]
# [('subject', 'http://www.wikidata.org/entity/Q536733'), ('label', '1975 Wimbledon Championships')]
# [('subject', 'http://www.wikidata.org/entity/Q683224'), ('label', '1984 Wimbledon Championships')]
# [('subject', 'http://www.wikidata.org/entity/Q245073'), ('label', '2011 Wimbledon Championships')]
# [('subject', 'http://www.wikidata.org/entity/Q289587'), ('label', '2012 Wimbledon Championships')]
# [('subject', 'http://www.wikidata.org/entity/Q525952'), ('label', '1992 Wimbledon Championships')]
# [('subject', 'http://www.wikidata.org/entity/Q559726'), ('label', '2013 Wimbledon Championships')]
# [('subject', 'http://www.wikidata.org/entity/Q658771'), ('label', '1977 Wimbledon Championships')]
# [('subject', 'http://www.wikidata.org/entity/Q912527'), ('label', '2001 Wimbledon Championships')]
# [('subject', 'http://www.wikidata.org/entity/Q241184'), ('label', '2006 Wimbledon Championships')]
# [('subject', 'http://www.wikidata.org/entity/Q521328'), ('label', '1973 Wimbledon Championships')]
# [('subject', 'http://www.wikidata.org/entity/Q780070'), ('label', '1991 Wimbledon Championships')]
# [('subject', 'http://www.wikidata.org/entity/Q856533'), ('label', '1994 Wimbledon Championships')]
# [('subject', 'http://www.wikidata.org/entity/Q726549'), ('label', '1879 Wimbledon Championship')]
# [('subject', 'http://www.wikidata.org/entity/Q1049052'), ('label', '1972 Wimbledon Championships')]
# [('subject', 'http://www.wikidata.org/entity/Q647980'), ('label', '1939 Wimbledon Championships')]
# [('subject', 'http://www.wikidata.org/entity/Q180151'), ('label', '1990 Wimbledon Championships')]
# [('subject', 'http://www.wikidata.org/entity/Q613346'), ('label', '1950 Wimbledon Championships')]
# [('subject', 'http://www.wikidata.org/entity/Q278548'), ('label', '1993 Wimbledon Championships')]
# [('subject', 'http://www.wikidata.org/entity/Q746669'), ('label', '2007 Wimbledon Championships')]
# [('subject', 'http://www.wikidata.org/entity/Q808721'), ('label', '1961 Wimbledon Championships')]
# [('subject', 'http://www.wikidata.org/entity/Q867067'), ('label', '1962 Wimbledon Championships')]
# [('subject', 'http://www.wikidata.org/entity/Q977440'), ('label', '1963 Wimbledon Championships')]
# [('subject', 'http://www.wikidata.org/entity/Q1644372'), ('label', '1906 Wimbledon Championships')]
# [('subject', 'http://www.wikidata.org/entity/Q727406'), ('label', '1999 Wimbledon Championships')]
# [('subject', 'http://www.wikidata.org/entity/Q1049039'), ('label', '1979 Wimbledon Championships')]
# [('subject', 'http://www.wikidata.org/entity/Q799308'), ('label', '1960 Wimbledon Championships')]
# [('subject', 'http://www.wikidata.org/entity/Q576785'), ('label', '1952 Wimbledon Championships')]
# [('subject', 'http://www.wikidata.org/entity/Q1728917'), ('label', '1920 Wimbledon Championships')]
# [('subject', 'http://www.wikidata.org/entity/Q2119696'), ('label', '1914 Wimbledon Championships')]
# [('subject', 'http://www.wikidata.org/entity/Q2120562'), ('label', '1895 Wimbledon Championships')]
# [('subject', 'http://www.wikidata.org/entity/Q212073'), ('label', '1924 Wimbledon Championships')]
# [('subject', 'http://www.wikidata.org/entity/Q2306362'), ('label', '1966 Wimbledon Championships')]
# [('subject', 'http://www.wikidata.org/entity/Q501884'), ('label', '1947 Wimbledon Championships')]
# [('subject', 'http://www.wikidata.org/entity/Q577168'), ('label', '1953 Wimbledon Championships')]
# [('subject', 'http://www.wikidata.org/entity/Q612679'), ('label', '1949 Wimbledon Championships')]
# [('subject', 'http://www.wikidata.org/entity/Q502011'), ('label', '1948 Wimbledon Championships')]
# [('subject', 'http://www.wikidata.org/entity/Q613356'), ('label', '1951 Wimbledon Championships')]
# [('subject', 'http://www.wikidata.org/entity/Q25344121'), ('label', '2017 Wimbledon Championships')]
# [('subject', 'http://www.wikidata.org/entity/Q912497'), ('label', '1997 Wimbledon Championships')]
# [('subject', 'http://www.wikidata.org/entity/Q423276'), ('label', '1938 Wimbledon Championships')]
# [('subject', 'http://www.wikidata.org/entity/Q653092'), ('label', '1896 Wimbledon Championships')]
# [('subject', 'http://www.wikidata.org/entity/Q912491'), ('label', '2000 Wimbledon Championships')]
# [('subject', 'http://www.wikidata.org/entity/Q54093953'), ('label', '2019 Wimbledon Championships')]
# [('subject', 'http://www.wikidata.org/entity/Q92032430'), ('label', '2021 Wimbledon Championships')]
# [('subject', 'http://www.wikidata.org/entity/Q840901'), ('label', '2002 Wimbledon Championships')]
# [('subject', 'http://www.wikidata.org/entity/Q729205'), ('label', '1982 Wimbledon Championships')]
# [('subject', 'http://www.wikidata.org/entity/Q951533'), ('label', '1987 Wimbledon Championships')]
# [('subject', 'http://www.wikidata.org/entity/Q1326511'), ('label', '1885 Wimbledon Championships')]
# [('subject', 'http://www.wikidata.org/entity/Q1724301'), ('label', '1887 Wimbledon Championships')]
# [('subject', 'http://www.wikidata.org/entity/Q47220'), ('label', '1886 Wimbledon Championships')]
# [('subject', 'http://www.wikidata.org/entity/Q1049023'), ('label', '1983 Wimbledon Championships')]
# [('subject', 'http://www.wikidata.org/entity/Q935551'), ('label', '1989 Wimbledon Championships')]
# [('subject', 'http://www.wikidata.org/entity/Q2296326'), ('label', '1880 Wimbledon Championship')]
# [('subject', 'http://www.wikidata.org/entity/Q1803935'), ('label', '1884 Wimbledon Championships')]
# [('subject', 'http://www.wikidata.org/entity/Q2120535'), ('label', '1888 Wimbledon Championships')]
# [('subject', 'http://www.wikidata.org/entity/Q951238'), ('label', '1889 Wimbledon Championships')]
# [('subject', 'http://www.wikidata.org/entity/Q746693'), ('label', '2005 Wimbledon Championships')]
# [('subject', 'http://www.wikidata.org/entity/Q404700'), ('label', '1931 Wimbledon Championships')]
# [('subject', 'http://www.wikidata.org/entity/Q404711'), ('label', '1932 Wimbledon Championships')]
# [('subject', 'http://www.wikidata.org/entity/Q423286'), ('label', '1934 Wimbledon Championships')]
# [('subject', 'http://www.wikidata.org/entity/Q423280'), ('label', '1937 Wimbledon Championships')]
# [('subject', 'http://www.wikidata.org/entity/Q1693428'), ('label', '1913 Wimbledon Championships')]
# [('subject', 'http://www.wikidata.org/entity/Q2121913'), ('label', '1912 Wimbledon Championships')]
# [('subject', 'http://www.wikidata.org/entity/Q337124'), ('label', '1926 Wimbledon Championships')]
# [('subject', 'http://www.wikidata.org/entity/Q663357'), ('label', '1986 Wimbledon Championships')]
# [('subject', 'http://www.wikidata.org/entity/Q2306097'), ('label', '1967 Wimbledon Championships')]
# [('subject', 'http://www.wikidata.org/entity/Q832484'), ('label', '2003 Wimbledon Championships')]
# [('subject', 'http://www.wikidata.org/entity/Q2119713'), ('label', '1893 Wimbledon Championships')]
# [('subject', 'http://www.wikidata.org/entity/Q588012'), ('label', '1919 Wimbledon Championships')]
# [('subject', 'http://www.wikidata.org/entity/Q725136'), ('label', '1959 Wimbledon Championships')]
# [('subject', 'http://www.wikidata.org/entity/Q1253069'), ('label', '1878 Wimbledon Championships')]
# [('subject', 'http://www.wikidata.org/entity/Q512632'), ('label', '1998 Wimbledon Championships')]
# [('subject', 'http://www.wikidata.org/entity/Q584490'), ('label', '1891 Wimbledon Championships')]
# [('subject', 'http://www.wikidata.org/entity/Q1639966'), ('label', '1922 Wimbledon Championships')]
# [('subject', 'http://www.wikidata.org/entity/Q2119724'), ('label', '1904 Wimbledon Championships')]
# [('subject', 'http://www.wikidata.org/entity/Q2121902'), ('label', '1902 Wimbledon Championships')]
# [('subject', 'http://www.wikidata.org/entity/Q584200'), ('label', '1907 Wimbledon Championships')]
# [('subject', 'http://www.wikidata.org/entity/Q762595'), ('label', '1892 Wimbledon Championships')]
# [('subject', 'http://www.wikidata.org/entity/Q978149'), ('label', '1894 Wimbledon Championships')]
# [('subject', 'http://www.wikidata.org/entity/Q572505'), ('label', '1995 Wimbledon Championships')]
# [('subject', 'http://www.wikidata.org/entity/Q912478'), ('label', '1996 Wimbledon Championships')]
# [('subject', 'http://www.wikidata.org/entity/Q219459'), ('label', '1925 Wimbledon Championships')]
# [('subject', 'http://www.wikidata.org/entity/Q212059'), ('label', '1923 Wimbledon Championships')]
# [('subject', 'http://www.wikidata.org/entity/Q107283026'), ('label', '2022 Wimbledon Championships')]
# [('subject', 'http://www.wikidata.org/entity/Q1934049'), ('label', '1877 Wimbledon Championship')]
# [('subject', 'http://www.wikidata.org/entity/Q2278189'), ('label', '1965 Wimbledon Championships')]
# [('subject', 'http://www.wikidata.org/entity/Q374001'), ('label', '1936 Wimbledon Championships')]
# [('subject', 'http://www.wikidata.org/entity/Q2278178'), ('label', '1964 Wimbledon Championships')]
# [('subject', 'http://www.wikidata.org/entity/Q2121875'), ('label', '1921 Wimbledon Championships')]
# 135

# %%
# s:what node? p:'part of' o:'2018 wimbledon chamiponships'
queryString = """
SELECT ?subject ?label
WHERE
{
   # ?subject wdt:P361 wd:Q30085309.
   
   # ?subject sc:name ?label.
}
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('subject', 'http://www.wikidata.org/entity/Q30098268'), ('label', "2018 Wimbledon Championships – Women's Singles")]
# [('subject', 'http://www.wikidata.org/entity/Q32358401'), ('label', '2018 Wimbledon Championships – Mixed Doubles')]
# [('subject', 'http://www.wikidata.org/entity/Q55639017'), ('label', '2018 Wimbledon Championships – Wheelchair Quad Doubles')]
# [('subject', 'http://www.wikidata.org/entity/Q55455418'), ('label', "2018 Wimbledon Championships – Wheelchair Men's Doubles")]
# [('subject', 'http://www.wikidata.org/entity/Q32357790'), ('label', "2018 Wimbledon Championships – Men's Doubles")]
# [('subject', 'http://www.wikidata.org/entity/Q32356704'), ('label', "2018 Wimbledon Championships – Women's Doubles")]
# [('subject', 'http://www.wikidata.org/entity/Q55381839'), ('label', "2018 Wimbledon Championships – Girls' Singles")]
# [('subject', 'http://www.wikidata.org/entity/Q54961494'), ('label', "2018 Wimbledon Championships – Men's Singles")]
# [('subject', 'http://www.wikidata.org/entity/Q55410290'), ('label', "2018 Wimbledon Championships – Girls' Doubles")]
# [('subject', 'http://www.wikidata.org/entity/Q55410361'), ('label', "2018 Wimbledon Championships – Boys' Doubles")]
# [('subject', 'http://www.wikidata.org/entity/Q55455404'), ('label', "2018 Wimbledon Championships – Wheelchair Women's Singles")]
# [('subject', 'http://www.wikidata.org/entity/Q55455410'), ('label', "2018 Wimbledon Championships – Wheelchair Men's Singles")]
# [('subject', 'http://www.wikidata.org/entity/Q55381833'), ('label', "2018 Wimbledon Championships – Boys' Singles")]
# [('subject', 'http://www.wikidata.org/entity/Q55455423'), ('label', "2018 Wimbledon Championships – Wheelchair Women's Doubles")]
# 14

# %%
# checking 'winner' property of node '2018 wimbledon championships – women's singles'
queryString = """
SELECT ?object ?label
WHERE
{
   wd:Q30098268 wdt:P1346 ?object.
   
   # ?object sc:name ?label.
}
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('object', 'http://www.wikidata.org/entity/Q77178'), ('label', 'Angelique Kerber')]
# 1

# %% [markdown]
# Final query for this task

# %%
# write your final query
queryString = """
SELECT ?tournament ?label_tournament ?winner ?label_winner
WHERE
{
   # ?tournament wdt:P361 wd:Q30085309.
   # ?tournament wdt:P1346 ?winner.
   
   # ?tournament sc:name ?label_tournament.
   # ?winner sc:name ?label_winner.
}
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('tournament', 'http://www.wikidata.org/entity/Q32357790'), ('label_tournament', "2018 Wimbledon Championships – Men's Doubles"), ('winner', 'http://www.wikidata.org/entity/Q53342'), ('label_winner', 'Mike Bryan')]
# [('tournament', 'http://www.wikidata.org/entity/Q54961494'), ('label_tournament', "2018 Wimbledon Championships – Men's Singles"), ('winner', 'http://www.wikidata.org/entity/Q5812'), ('label_winner', 'Novak Djokovic')]
# [('tournament', 'http://www.wikidata.org/entity/Q30098268'), ('label_tournament', "2018 Wimbledon Championships – Women's Singles"), ('winner', 'http://www.wikidata.org/entity/Q77178'), ('label_winner', 'Angelique Kerber')]
# [('tournament', 'http://www.wikidata.org/entity/Q32356704'), ('label_tournament', "2018 Wimbledon Championships – Women's Doubles"), ('winner', 'http://www.wikidata.org/entity/Q11052500'), ('label_winner', 'Barbora Krejčíková')]
# [('tournament', 'http://www.wikidata.org/entity/Q55455423'), ('label_tournament', "2018 Wimbledon Championships – Wheelchair Women's Doubles"), ('winner', 'http://www.wikidata.org/entity/Q16224602'), ('label_winner', 'Yui Kamiji')]
# [('tournament', 'http://www.wikidata.org/entity/Q55455410'), ('label_tournament', "2018 Wimbledon Championships – Wheelchair Men's Singles"), ('winner', 'http://www.wikidata.org/entity/Q6027963'), ('label_winner', 'Stefan Olsson')]
# [('tournament', 'http://www.wikidata.org/entity/Q55639017'), ('label_tournament', '2018 Wimbledon Championships – Wheelchair Quad Doubles'), ('winner', 'http://www.wikidata.org/entity/Q13512827'), ('label_winner', 'Andrew Lapthorne')]
# [('tournament', 'http://www.wikidata.org/entity/Q55381839'), ('label_tournament', "2018 Wimbledon Championships – Girls' Singles"), ('winner', 'http://www.wikidata.org/entity/Q26840238'), ('label_winner', 'Iga Świątek')]
# [('tournament', 'http://www.wikidata.org/entity/Q55455404'), ('label_tournament', "2018 Wimbledon Championships – Wheelchair Women's Singles"), ('winner', 'http://www.wikidata.org/entity/Q24574661'), ('label_winner', 'Diede de Groot')]
# [('tournament', 'http://www.wikidata.org/entity/Q55455423'), ('label_tournament', "2018 Wimbledon Championships – Wheelchair Women's Doubles"), ('winner', 'http://www.wikidata.org/entity/Q24574661'), ('label_winner', 'Diede de Groot')]
# [('tournament', 'http://www.wikidata.org/entity/Q55455418'), ('label_tournament', "2018 Wimbledon Championships – Wheelchair Men's Doubles"), ('winner', 'http://www.wikidata.org/entity/Q26951148'), ('label_winner', 'Alfie Hewett')]
# [('tournament', 'http://www.wikidata.org/entity/Q32356704'), ('label_tournament', "2018 Wimbledon Championships – Women's Doubles"), ('winner', 'http://www.wikidata.org/entity/Q3720044'), ('label_winner', 'Kateřina Siniaková')]
# [('tournament', 'http://www.wikidata.org/entity/Q32358401'), ('label_tournament', '2018 Wimbledon Championships – Mixed Doubles'), ('winner', 'http://www.wikidata.org/entity/Q2216368'), ('label_winner', 'Nicole Melichar-Martinez')]
# [('tournament', 'http://www.wikidata.org/entity/Q32358401'), ('label_tournament', '2018 Wimbledon Championships – Mixed Doubles'), ('winner', 'http://www.wikidata.org/entity/Q457476'), ('label_winner', 'Alexander Peya')]
# [('tournament', 'http://www.wikidata.org/entity/Q55410361'), ('label_tournament', "2018 Wimbledon Championships – Boys' Doubles"), ('winner', 'http://www.wikidata.org/entity/Q55569239'), ('label_winner', 'Yankı Erel')]
# [('tournament', 'http://www.wikidata.org/entity/Q55410290'), ('label_tournament', "2018 Wimbledon Championships – Girls' Doubles"), ('winner', 'http://www.wikidata.org/entity/Q44465805'), ('label_winner', 'Wang Xinyu')]
# [('tournament', 'http://www.wikidata.org/entity/Q55410290'), ('label_tournament', "2018 Wimbledon Championships – Girls' Doubles"), ('winner', 'http://www.wikidata.org/entity/Q41799108'), ('label_winner', 'Wang Xiyu')]
# [('tournament', 'http://www.wikidata.org/entity/Q55381833'), ('label_tournament', "2018 Wimbledon Championships – Boys' Singles"), ('winner', 'http://www.wikidata.org/entity/Q47516746'), ('label_winner', 'Tseng Chun-hsin')]
# 18

# %% [markdown]
# ## Task 6
# Consider the tennis players born after 1975, return who won more Grand Slams and cut the result to the top-10 (the result set must be a list of triples player IRI, label and #victories).

# %%
# write your queries
# getting tennis players who has 'date of birth' property after 1975
queryString = """
SELECT ?player ?label ?date
WHERE
{
   # ?player wdt:P106 wd:Q10833314.
   # ?player wdt:P569 ?date.
   
   FILTER (datatype(?date) = xsd:dateTime)
   FILTER ("1975-01-01T00:00:00Z"^^xsd:dateTime <= ?date)
   
   # ?player sc:name ?label.
}
LIMIT 50
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('player', 'http://www.wikidata.org/entity/Q138094'), ('label', 'Anna Karolína Schmiedlová'), ('date', '1994-09-13T00:00:00Z')]
# [('player', 'http://www.wikidata.org/entity/Q15197746'), ('label', 'Wesley Koolhof'), ('date', '1989-04-17T00:00:00Z')]
# [('player', 'http://www.wikidata.org/entity/Q15880574'), ('label', 'Paul Oosterbaan'), ('date', '1995-07-08T00:00:00Z')]
# [('player', 'http://www.wikidata.org/entity/Q240837'), ('label', 'Rika Fujiwara'), ('date', '1981-09-19T00:00:00Z')]
# [('player', 'http://www.wikidata.org/entity/Q4134097'), ('label', 'Margarita Gasparyan'), ('date', '1994-09-01T00:00:00Z')]
# [('player', 'http://www.wikidata.org/entity/Q16224631'), ('label', 'Lee So-ra'), ('date', '1994-07-22T00:00:00Z')]
# [('player', 'http://www.wikidata.org/entity/Q7281705'), ('label', 'Radu Albot'), ('date', '1989-11-11T00:00:00Z')]
# [('player', 'http://www.wikidata.org/entity/Q18918709'), ('label', 'Markéta Vondroušová'), ('date', '1999-06-28T00:00:00Z')]
# [('player', 'http://www.wikidata.org/entity/Q17291218'), ('label', 'Djordje Djokovic'), ('date', '1995-07-07T00:00:00Z')]
# [('player', 'http://www.wikidata.org/entity/Q17323657'), ('label', 'Sviatlana Pirazhenka'), ('date', '1992-09-12T00:00:00Z')]
# [('player', 'http://www.wikidata.org/entity/Q17327545'), ('label', 'Marcelo Zormann'), ('date', '1996-06-10T00:00:00Z')]
# [('player', 'http://www.wikidata.org/entity/Q17525743'), ('label', 'Sanaz Marand'), ('date', '1988-06-21T00:00:00Z')]
# [('player', 'http://www.wikidata.org/entity/Q193661'), ('label', 'Stan Wawrinka'), ('date', '1985-03-28T00:00:00Z')]
# [('player', 'http://www.wikidata.org/entity/Q3597288'), ('label', 'Marko Djokovic'), ('date', '1991-08-20T00:00:00Z')]
# [('player', 'http://www.wikidata.org/entity/Q76338'), ('label', 'Sabine Lisicki'), ('date', '1989-09-22T00:00:00Z')]
# [('player', 'http://www.wikidata.org/entity/Q966542'), ('label', 'Roberto Bautista Agut'), ('date', '1988-04-14T00:00:00Z')]
# [('player', 'http://www.wikidata.org/entity/Q12768184'), ('label', 'Jozef Kovalík'), ('date', '1992-11-04T00:00:00Z')]
# [('player', 'http://www.wikidata.org/entity/Q237146'), ('label', 'Lara Arruabarrena'), ('date', '1992-03-20T00:00:00Z')]
# [('player', 'http://www.wikidata.org/entity/Q17612829'), ('label', 'Hunter Reese'), ('date', '1993-01-11T00:00:00Z')]
# [('player', 'http://www.wikidata.org/entity/Q17626628'), ('label', 'Ernesto Escobedo'), ('date', '1996-07-04T00:00:00Z')]
# [('player', 'http://www.wikidata.org/entity/Q4169985'), ('label', 'Bermet Duvanaeva'), ('date', '1988-01-28T00:00:00Z')]
# [('player', 'http://www.wikidata.org/entity/Q18129396'), ('label', 'Gao Xin'), ('date', '1994-05-12T00:00:00Z')]
# [('player', 'http://www.wikidata.org/entity/Q19406'), ('label', 'David Goffin'), ('date', '1990-12-07T00:00:00Z')]
# [('player', 'http://www.wikidata.org/entity/Q26799554'), ('label', 'Jeffrey John Wolf'), ('date', '1998-12-21T00:00:00Z')]
# [('player', 'http://www.wikidata.org/entity/Q355333'), ('label', 'Marcin Matkowski'), ('date', '1981-01-15T00:00:00Z')]
# [('player', 'http://www.wikidata.org/entity/Q4800760'), ('label', 'Wang Qiang'), ('date', '1992-01-14T00:00:00Z')]
# [('player', 'http://www.wikidata.org/entity/Q17364412'), ('label', 'Maximilian Marterer'), ('date', '1995-06-15T00:00:00Z')]
# [('player', 'http://www.wikidata.org/entity/Q19330576'), ('label', 'Darren Walsh'), ('date', '1989-01-16T00:00:00Z')]
# [('player', 'http://www.wikidata.org/entity/Q5880437'), ('label', 'Gisela Riera'), ('date', '1976-05-07T00:00:00Z')]
# [('player', 'http://www.wikidata.org/entity/Q6376017'), ('label', 'Kateřina Böhmová'), ('date', '1986-11-18T00:00:00Z')]
# [('player', 'http://www.wikidata.org/entity/Q14905846'), ('label', 'Borna Ćorić'), ('date', '1996-11-14T00:00:00Z')]
# [('player', 'http://www.wikidata.org/entity/Q207352'), ('label', 'Agnieszka Radwańska'), ('date', '1989-03-06T00:00:00Z')]
# [('player', 'http://www.wikidata.org/entity/Q20968624'), ('label', 'Viktória Kužmová'), ('date', '1998-05-11T00:00:00Z')]
# [('player', 'http://www.wikidata.org/entity/Q20982979'), ('label', 'Miyu Kato'), ('date', '1994-11-21T00:00:00Z')]
# [('player', 'http://www.wikidata.org/entity/Q20983768'), ('label', 'Kerstin Peckl'), ('date', '1989-09-02T00:00:00Z')]
# [('player', 'http://www.wikidata.org/entity/Q21001023'), ('label', 'Facundo Mena'), ('date', '1992-09-22T00:00:00Z')]
# [('player', 'http://www.wikidata.org/entity/Q21622155'), ('label', 'Richard Muzaev'), ('date', '1992-03-21T00:00:00Z')]
# [('player', 'http://www.wikidata.org/entity/Q21622265'), ('label', 'Akiko Ōmae'), ('date', '1993-01-29T00:00:00Z')]
# [('player', 'http://www.wikidata.org/entity/Q21970595'), ('label', 'Eléonora Molinaro'), ('date', '2000-09-04T00:00:00Z')]
# [('player', 'http://www.wikidata.org/entity/Q312343'), ('label', 'Milos Raonic'), ('date', '1990-12-27T00:00:00Z')]
# [('player', 'http://www.wikidata.org/entity/Q22086227'), ('label', 'Ellen Perez'), ('date', '1995-10-10T00:00:00Z')]
# [('player', 'http://www.wikidata.org/entity/Q22958938'), ('label', 'Alex de Minaur'), ('date', '1999-02-17T00:00:00Z')]
# [('player', 'http://www.wikidata.org/entity/Q22959065'), ('label', 'Blake Ellis'), ('date', '1999-01-06T00:00:00Z')]
# [('player', 'http://www.wikidata.org/entity/Q22961763'), ('label', 'Nurin Nabilah Roslan'), ('date', '1998-01-13T00:00:00Z')]
# [('player', 'http://www.wikidata.org/entity/Q26207574'), ('label', 'Doaa el-Ghobashy'), ('date', '1994-11-08T00:00:00Z')]
# [('player', 'http://www.wikidata.org/entity/Q26209630'), ('label', 'Zhu Aiwen'), ('date', '1994-09-22T00:00:00Z')]
# [('player', 'http://www.wikidata.org/entity/Q26210785'), ('label', 'Kaden Hensel'), ('date', '1986-06-05T00:00:00Z')]
# [('player', 'http://www.wikidata.org/entity/Q26269760'), ('label', 'Giorgia Marchetti'), ('date', '1995-01-21T00:00:00Z')]
# [('player', 'http://www.wikidata.org/entity/Q27032196'), ('label', 'Polina Merenkova'), ('date', '1995-11-11T00:00:00Z')]
# [('player', 'http://www.wikidata.org/entity/Q27049237'), ('label', 'Ljubomir Čelebić'), ('date', '1991-09-15T00:00:00Z')]
# 50

# %%
# getting all editions of all grand slams with the iri of each grand slam separately
queryString = """
SELECT DISTINCT ?eventWise_edition_of_grand_slam ?label
WHERE
{
   values ?grand_slam { wd:Q60874 wd:Q43605 wd:Q41520 wd:Q123577 }
   
   # ?yearWise_edition_of_grand_slam wdt:P31 ?grand_slam.
   # ?eventWise_edition_of_grand_slam wdt:P361 ?yearWise_edition_of_grand_slam.
   
   # ?eventWise_edition_of_grand_slam sc:name ?label.
}
LIMIT 50
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('eventWise_edition_of_grand_slam', 'http://www.wikidata.org/entity/Q15851905'), ('label', "1970 US Open – Men's Doubles")]
# [('eventWise_edition_of_grand_slam', 'http://www.wikidata.org/entity/Q15854748'), ('label', "1971 Wimbledon Championships – Men's Doubles")]
# [('eventWise_edition_of_grand_slam', 'http://www.wikidata.org/entity/Q15854755'), ('label', "1978 Wimbledon Championships – Men's Doubles")]
# [('eventWise_edition_of_grand_slam', 'http://www.wikidata.org/entity/Q15854764'), ('label', "2012 Wimbledon Championships – Ladies' Invitation Doubles")]
# [('eventWise_edition_of_grand_slam', 'http://www.wikidata.org/entity/Q16040928'), ('label', "1928 French Championships – Women's Doubles")]
# [('eventWise_edition_of_grand_slam', 'http://www.wikidata.org/entity/Q16040959'), ('label', "1938 French Championships – Women's Doubles")]
# [('eventWise_edition_of_grand_slam', 'http://www.wikidata.org/entity/Q17016282'), ('label', "2014 French Open – Wheelchair Men's Singles")]
# [('eventWise_edition_of_grand_slam', 'http://www.wikidata.org/entity/Q17016314'), ('label', "2014 French Open – Wheelchair Women's Doubles")]
# [('eventWise_edition_of_grand_slam', 'http://www.wikidata.org/entity/Q17288557'), ('label', "2014 Wimbledon Championships – Ladies' Invitation Doubles")]
# [('eventWise_edition_of_grand_slam', 'http://www.wikidata.org/entity/Q20895284'), ('label', '2015 US Open – Mixed Doubles')]
# [('eventWise_edition_of_grand_slam', 'http://www.wikidata.org/entity/Q16618678'), ('label', "1912 U.S. National Championships – Women's Singles")]
# [('eventWise_edition_of_grand_slam', 'http://www.wikidata.org/entity/Q17638970'), ('label', "1930 U.S. National Championships – Men's Singles")]
# [('eventWise_edition_of_grand_slam', 'http://www.wikidata.org/entity/Q22040148'), ('label', "2016 Australian Open – Men's Singles Qualifying")]
# [('eventWise_edition_of_grand_slam', 'http://www.wikidata.org/entity/Q22231236'), ('label', "2016 Australian Open – Boys' Doubles")]
# [('eventWise_edition_of_grand_slam', 'http://www.wikidata.org/entity/Q22956224'), ('label', "2017 Australian Open – Men's Singles")]
# [('eventWise_edition_of_grand_slam', 'http://www.wikidata.org/entity/Q24207115'), ('label', "1998 US Open – Women's Doubles Qualifying")]
# [('eventWise_edition_of_grand_slam', 'http://www.wikidata.org/entity/Q29096778'), ('label', "1998 US Open – Men's Doubles Qualifying")]
# [('eventWise_edition_of_grand_slam', 'http://www.wikidata.org/entity/Q25344122'), ('label', "2017 Wimbledon Championships – Women's Singles")]
# [('eventWise_edition_of_grand_slam', 'http://www.wikidata.org/entity/Q30098268'), ('label', "2018 Wimbledon Championships – Women's Singles")]
# [('eventWise_edition_of_grand_slam', 'http://www.wikidata.org/entity/Q30689179'), ('label', '2017 French Open – Day-by-day Summaries')]
# [('eventWise_edition_of_grand_slam', 'http://www.wikidata.org/entity/Q1753915'), ('label', "1966 Wimbledon Championships – Men's Singles")]
# [('eventWise_edition_of_grand_slam', 'http://www.wikidata.org/entity/Q1755228'), ('label', "1965 U.S. National Championships – Men's Singles")]
# [('eventWise_edition_of_grand_slam', 'http://www.wikidata.org/entity/Q1060393'), ('label', "1973 Wimbledon Championships – Men's Singles")]
# [('eventWise_edition_of_grand_slam', 'http://www.wikidata.org/entity/Q1455356'), ('label', "1980 French Open – Women's Doubles")]
# [('eventWise_edition_of_grand_slam', 'http://www.wikidata.org/entity/Q1751593'), ('label', "1958 Australian Championships – Men's Singles")]
# [('eventWise_edition_of_grand_slam', 'http://www.wikidata.org/entity/Q2311386'), ('label', "1980 French Open – Men's Singles")]
# [('eventWise_edition_of_grand_slam', 'http://www.wikidata.org/entity/Q2406558'), ('label', "1958 Australian Championships – Women's Singles")]
# [('eventWise_edition_of_grand_slam', 'http://www.wikidata.org/entity/Q378570'), ('label', "1975 Wimbledon Championships – Men's Singles")]
# [('eventWise_edition_of_grand_slam', 'http://www.wikidata.org/entity/Q3883664'), ('label', '1980 French Open – Mixed Doubles')]
# [('eventWise_edition_of_grand_slam', 'http://www.wikidata.org/entity/Q3883665'), ('label', "1980 French Open – Men's Doubles")]
# [('eventWise_edition_of_grand_slam', 'http://www.wikidata.org/entity/Q536077'), ('label', "1974 Wimbledon Championships – Men's Singles")]
# [('eventWise_edition_of_grand_slam', 'http://www.wikidata.org/entity/Q550077'), ('label', "1989 US Open – Women's Singles")]
# [('eventWise_edition_of_grand_slam', 'http://www.wikidata.org/entity/Q571749'), ('label', "1988 US Open – Women's Singles")]
# [('eventWise_edition_of_grand_slam', 'http://www.wikidata.org/entity/Q925347'), ('label', "1980 French Open – Women's Singles")]
# [('eventWise_edition_of_grand_slam', 'http://www.wikidata.org/entity/Q963993'), ('label', "1990 US Open – Women's Singles")]
# [('eventWise_edition_of_grand_slam', 'http://www.wikidata.org/entity/Q1455334'), ('label', "1970 French Open – Women's Singles")]
# [('eventWise_edition_of_grand_slam', 'http://www.wikidata.org/entity/Q1972216'), ('label', "1975 Australian Open – Men's Singles")]
# [('eventWise_edition_of_grand_slam', 'http://www.wikidata.org/entity/Q586490'), ('label', "1972 Australian Open – Women's Singles")]
# [('eventWise_edition_of_grand_slam', 'http://www.wikidata.org/entity/Q594977'), ('label', "1969 French Open – Women's Singles")]
# [('eventWise_edition_of_grand_slam', 'http://www.wikidata.org/entity/Q781672'), ('label', "1973 Australian Open – Women's Singles")]
# [('eventWise_edition_of_grand_slam', 'http://www.wikidata.org/entity/Q781699'), ('label', "1975 Australian Open – Women's Singles")]
# [('eventWise_edition_of_grand_slam', 'http://www.wikidata.org/entity/Q1059671'), ('label', "1970 US Open – Women's Singles")]
# [('eventWise_edition_of_grand_slam', 'http://www.wikidata.org/entity/Q1275316'), ('label', "1957 Wimbledon Championships – Men's Doubles")]
# [('eventWise_edition_of_grand_slam', 'http://www.wikidata.org/entity/Q1397235'), ('label', '1957 Wimbledon Championships – Mixed Doubles')]
# [('eventWise_edition_of_grand_slam', 'http://www.wikidata.org/entity/Q1431811'), ('label', "1957 Wimbledon Championships – Women's Doubles")]
# [('eventWise_edition_of_grand_slam', 'http://www.wikidata.org/entity/Q655310'), ('label', "1955 Wimbledon Championships – Men's Singles")]
# [('eventWise_edition_of_grand_slam', 'http://www.wikidata.org/entity/Q655327'), ('label', "1956 Wimbledon Championships – Men's Singles")]
# [('eventWise_edition_of_grand_slam', 'http://www.wikidata.org/entity/Q655345'), ('label', "1956 Wimbledon Championships – Women's Singles")]
# [('eventWise_edition_of_grand_slam', 'http://www.wikidata.org/entity/Q657674'), ('label', "1958 Wimbledon Championships – Women's Singles")]
# [('eventWise_edition_of_grand_slam', 'http://www.wikidata.org/entity/Q657685'), ('label', "1957 Wimbledon Championships – Men's Singles")]
# 50

# %%
# counting all victories of top 10 players
queryString = """
SELECT ?player ?label (COUNT(?victory) AS ?num_victory)
WHERE
{
    # ?player wdt:P106 wd:Q10833314.
    # ?player wdt:P2522 ?victory.
    
    # ?player sc:name ?label.
}
GROUP BY ?player ?label
ORDER BY DESC(?num_victory)
LIMIT 10
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('player', 'http://www.wikidata.org/entity/Q1426'), ('label', 'Roger Federer'), ('num_victory', '29')]
# [('player', 'http://www.wikidata.org/entity/Q202342'), ('label', 'Margaret Court'), ('num_victory', '24')]
# [('player', 'http://www.wikidata.org/entity/Q54543'), ('label', 'Helen Wills'), ('num_victory', '19')]
# [('player', 'http://www.wikidata.org/entity/Q54527'), ('label', 'Billie Jean King'), ('num_victory', '12')]
# [('player', 'http://www.wikidata.org/entity/Q53390'), ('label', 'Maureen Connolly'), ('num_victory', '9')]
# [('player', 'http://www.wikidata.org/entity/Q34276'), ('label', 'Garbiñe Muguruza'), ('num_victory', '8')]
# [('player', 'http://www.wikidata.org/entity/Q233247'), ('label', 'Maria Bueno'), ('num_victory', '7')]
# [('player', 'http://www.wikidata.org/entity/Q11662'), ('label', 'Steffi Graf'), ('num_victory', '6')]
# [('player', 'http://www.wikidata.org/entity/Q53564'), ('label', 'Doris Hart'), ('num_victory', '6')]
# [('player', 'http://www.wikidata.org/entity/Q48351'), ('label', 'Dorothy Round'), ('num_victory', '6')]
# 10

# %% [markdown]
# Final query for this task

# %%
# write your final query
queryString = """
SELECT ?player ?label_player (COUNT(*) AS ?num_victory)
WHERE
{
    # ?player wdt:P106 wd:Q10833314.
    # ?player wdt:P2522 ?victory.
    
    FILTER (?victory = ?eventWise_edition_of_grand_slam)
    
    # ?player sc:name ?label_player.
    {
        SELECT DISTINCT ?eventWise_edition_of_grand_slam ?label
        WHERE
        {
           values ?grand_slam { wd:Q60874 wd:Q43605 wd:Q41520 wd:Q123577 }

           # ?yearWise_edition_of_grand_slam wdt:P31 ?grand_slam.
           # ?eventWise_edition_of_grand_slam wdt:P361 ?yearWise_edition_of_grand_slam.

           # ?eventWise_edition_of_grand_slam sc:name ?label.
        }
    }
    
}
GROUP BY ?player ?label_player 
ORDER BY DESC(?num_victory)
LIMIT 10
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('player', 'http://www.wikidata.org/entity/Q202342'), ('label_player', 'Margaret Court'), ('num_victory', '24')]
# [('player', 'http://www.wikidata.org/entity/Q1426'), ('label_player', 'Roger Federer'), ('num_victory', '20')]
# [('player', 'http://www.wikidata.org/entity/Q54543'), ('label_player', 'Helen Wills'), ('num_victory', '19')]
# [('player', 'http://www.wikidata.org/entity/Q54527'), ('label_player', 'Billie Jean King'), ('num_victory', '12')]
# [('player', 'http://www.wikidata.org/entity/Q53390'), ('label_player', 'Maureen Connolly'), ('num_victory', '9')]
# [('player', 'http://www.wikidata.org/entity/Q233247'), ('label_player', 'Maria Bueno'), ('num_victory', '7')]
# [('player', 'http://www.wikidata.org/entity/Q11662'), ('label_player', 'Steffi Graf'), ('num_victory', '6')]
# [('player', 'http://www.wikidata.org/entity/Q53564'), ('label_player', 'Doris Hart'), ('num_victory', '6')]
# [('player', 'http://www.wikidata.org/entity/Q48351'), ('label_player', 'Dorothy Round'), ('num_victory', '6')]
# [('player', 'http://www.wikidata.org/entity/Q53550'), ('label_player', 'Althea Gibson'), ('num_victory', '5')]
# 10

# %% [markdown]
# ## Task 7
# Consider the country for sport property of the tennis player (NO Country of citizenship). Return the countries with at least one player who won at least one edition of each Grand Slam (the result set must be a list of country IRI and label).

# %%
# write your queries
# checking 'country for sport' property of node 'Roger Federer'
queryString = """
SELECT ?object ?label
WHERE
{
   wd:Q1426 wdt:P1532 ?object.
   
   # ?object sc:name ?label.
}
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('object', 'http://www.wikidata.org/entity/Q39'), ('label', 'Switzerland')]
# 1

# %%
# getting all tennis players
queryString = """
SELECT DISTINCT ?subject ?label
WHERE
{
   # ?subject wdt:P106 wd:Q10833314.
   
   # ?subject sc:name ?label.
}
LIMIT 50
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('subject', 'http://www.wikidata.org/entity/Q1683632'), ('label', 'Jaroslav Navrátil')]
# [('subject', 'http://www.wikidata.org/entity/Q138094'), ('label', 'Anna Karolína Schmiedlová')]
# [('subject', 'http://www.wikidata.org/entity/Q15197746'), ('label', 'Wesley Koolhof')]
# [('subject', 'http://www.wikidata.org/entity/Q1558013'), ('label', 'Pierre Barthès')]
# [('subject', 'http://www.wikidata.org/entity/Q15849678'), ('label', 'Sue Partridge')]
# [('subject', 'http://www.wikidata.org/entity/Q15880574'), ('label', 'Paul Oosterbaan')]
# [('subject', 'http://www.wikidata.org/entity/Q240837'), ('label', 'Rika Fujiwara')]
# [('subject', 'http://www.wikidata.org/entity/Q4134097'), ('label', 'Margarita Gasparyan')]
# [('subject', 'http://www.wikidata.org/entity/Q589611'), ('label', 'Philippe Chatrier')]
# [('subject', 'http://www.wikidata.org/entity/Q16009513'), ('label', 'James Bayley')]
# [('subject', 'http://www.wikidata.org/entity/Q16023406'), ('label', 'Samuel T. Chase')]
# [('subject', 'http://www.wikidata.org/entity/Q16063202'), ('label', 'Agnete Goldschmidt')]
# [('subject', 'http://www.wikidata.org/entity/Q16065254'), ('label', 'Thorkil Hillerup')]
# [('subject', 'http://www.wikidata.org/entity/Q16067006'), ('label', 'Lois Moyes Bickle')]
# [('subject', 'http://www.wikidata.org/entity/Q1660141'), ('label', 'Perry Jones')]
# [('subject', 'http://www.wikidata.org/entity/Q299959'), ('label', 'Eileen Bennett Whittingstall')]
# [('subject', 'http://www.wikidata.org/entity/Q16203224'), ('label', 'Frederick Campbell Colston')]
# [('subject', 'http://www.wikidata.org/entity/Q16204467'), ('label', 'Andrew Drew')]
# [('subject', 'http://www.wikidata.org/entity/Q16208155'), ('label', 'Chris Forney')]
# [('subject', 'http://www.wikidata.org/entity/Q16210951'), ('label', 'N. M. Smith')]
# [('subject', 'http://www.wikidata.org/entity/Q16219279'), ('label', 'William S. Bond')]
# [('subject', 'http://www.wikidata.org/entity/Q16219370'), ('label', 'John Strachan')]
# [('subject', 'http://www.wikidata.org/entity/Q16224596'), ('label', 'David Kabiller')]
# [('subject', 'http://www.wikidata.org/entity/Q16224618'), ('label', 'Janet Lagasse')]
# [('subject', 'http://www.wikidata.org/entity/Q16224631'), ('label', 'Lee So-ra')]
# [('subject', 'http://www.wikidata.org/entity/Q459223'), ('label', 'Paul Lebreton')]
# [('subject', 'http://www.wikidata.org/entity/Q7281705'), ('label', 'Radu Albot')]
# [('subject', 'http://www.wikidata.org/entity/Q17189986'), ('label', 'Will Coghlan')]
# [('subject', 'http://www.wikidata.org/entity/Q18918709'), ('label', 'Markéta Vondroušová')]
# [('subject', 'http://www.wikidata.org/entity/Q6408932'), ('label', 'Kim Jones')]
# [('subject', 'http://www.wikidata.org/entity/Q7176198'), ('label', 'Peter Oatey')]
# [('subject', 'http://www.wikidata.org/entity/Q17291218'), ('label', 'Djordje Djokovic')]
# [('subject', 'http://www.wikidata.org/entity/Q17302035'), ('label', 'Mary Hamm')]
# [('subject', 'http://www.wikidata.org/entity/Q17303008'), ('label', 'Petra Hradecká')]
# [('subject', 'http://www.wikidata.org/entity/Q17323657'), ('label', 'Sviatlana Pirazhenka')]
# [('subject', 'http://www.wikidata.org/entity/Q17327545'), ('label', 'Marcelo Zormann')]
# [('subject', 'http://www.wikidata.org/entity/Q17525743'), ('label', 'Sanaz Marand')]
# [('subject', 'http://www.wikidata.org/entity/Q193661'), ('label', 'Stan Wawrinka')]
# [('subject', 'http://www.wikidata.org/entity/Q3597288'), ('label', 'Marko Djokovic')]
# [('subject', 'http://www.wikidata.org/entity/Q76338'), ('label', 'Sabine Lisicki')]
# [('subject', 'http://www.wikidata.org/entity/Q966542'), ('label', 'Roberto Bautista Agut')]
# [('subject', 'http://www.wikidata.org/entity/Q12768184'), ('label', 'Jozef Kovalík')]
# [('subject', 'http://www.wikidata.org/entity/Q17442289'), ('label', 'David Sherbeck')]
# [('subject', 'http://www.wikidata.org/entity/Q237146'), ('label', 'Lara Arruabarrena')]
# [('subject', 'http://www.wikidata.org/entity/Q15693148'), ('label', 'Lo Man Wai')]
# [('subject', 'http://www.wikidata.org/entity/Q17612829'), ('label', 'Hunter Reese')]
# [('subject', 'http://www.wikidata.org/entity/Q17626628'), ('label', 'Ernesto Escobedo')]
# [('subject', 'http://www.wikidata.org/entity/Q53410'), ('label', 'John Doeg')]
# [('subject', 'http://www.wikidata.org/entity/Q54546'), ('label', 'Nancy Richey')]
# [('subject', 'http://www.wikidata.org/entity/Q4169985'), ('label', 'Bermet Duvanaeva')]
# 50

# %%
# getting 'country for sport' property of all players
queryString = """
SELECT DISTINCT ?object ?label
WHERE
{
   # ?player wdt:P106 wd:Q10833314.
   # ?player wdt:P1532 ?object.
   
   # ?object sc:name ?label.
}
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('object', 'http://www.wikidata.org/entity/Q216923'), ('label', 'Chinese Taipei')]
# [('object', 'http://www.wikidata.org/entity/Q1019'), ('label', 'Madagascar')]
# [('object', 'http://www.wikidata.org/entity/Q129286'), ('label', 'British India')]
# [('object', 'http://www.wikidata.org/entity/Q142'), ('label', 'France')]
# [('object', 'http://www.wikidata.org/entity/Q145'), ('label', 'United Kingdom')]
# [('object', 'http://www.wikidata.org/entity/Q148'), ('label', "People's Republic of China")]
# [('object', 'http://www.wikidata.org/entity/Q15180'), ('label', 'Soviet Union')]
# [('object', 'http://www.wikidata.org/entity/Q155'), ('label', 'Brazil')]
# [('object', 'http://www.wikidata.org/entity/Q159'), ('label', 'Russia')]
# [('object', 'http://www.wikidata.org/entity/Q16'), ('label', 'Canada')]
# [('object', 'http://www.wikidata.org/entity/Q16957'), ('label', 'German Democratic Republic')]
# [('object', 'http://www.wikidata.org/entity/Q17'), ('label', 'Japan')]
# [('object', 'http://www.wikidata.org/entity/Q172579'), ('label', 'Kingdom of Italy')]
# [('object', 'http://www.wikidata.org/entity/Q174193'), ('label', 'United Kingdom of Great Britain and Ireland')]
# [('object', 'http://www.wikidata.org/entity/Q183'), ('label', 'Germany')]
# [('object', 'http://www.wikidata.org/entity/Q184'), ('label', 'Belarus')]
# [('object', 'http://www.wikidata.org/entity/Q191'), ('label', 'Estonia')]
# [('object', 'http://www.wikidata.org/entity/Q20'), ('label', 'Norway')]
# [('object', 'http://www.wikidata.org/entity/Q21'), ('label', 'England')]
# [('object', 'http://www.wikidata.org/entity/Q211'), ('label', 'Latvia')]
# [('object', 'http://www.wikidata.org/entity/Q212'), ('label', 'Ukraine')]
# [('object', 'http://www.wikidata.org/entity/Q213'), ('label', 'Czech Republic')]
# [('object', 'http://www.wikidata.org/entity/Q214'), ('label', 'Slovakia')]
# [('object', 'http://www.wikidata.org/entity/Q215'), ('label', 'Slovenia')]
# [('object', 'http://www.wikidata.org/entity/Q217'), ('label', 'Moldova')]
# [('object', 'http://www.wikidata.org/entity/Q218'), ('label', 'Romania')]
# [('object', 'http://www.wikidata.org/entity/Q219'), ('label', 'Bulgaria')]
# [('object', 'http://www.wikidata.org/entity/Q221'), ('label', 'North Macedonia')]
# [('object', 'http://www.wikidata.org/entity/Q224'), ('label', 'Croatia')]
# [('object', 'http://www.wikidata.org/entity/Q229'), ('label', 'Cyprus')]
# [('object', 'http://www.wikidata.org/entity/Q230'), ('label', 'Georgia')]
# [('object', 'http://www.wikidata.org/entity/Q232'), ('label', 'Kazakhstan')]
# [('object', 'http://www.wikidata.org/entity/Q252'), ('label', 'Indonesia')]
# [('object', 'http://www.wikidata.org/entity/Q258'), ('label', 'South Africa')]
# [('object', 'http://www.wikidata.org/entity/Q27'), ('label', 'Ireland')]
# [('object', 'http://www.wikidata.org/entity/Q28'), ('label', 'Hungary')]
# [('object', 'http://www.wikidata.org/entity/Q29'), ('label', 'Spain')]
# [('object', 'http://www.wikidata.org/entity/Q29999'), ('label', 'Kingdom of the Netherlands')]
# [('object', 'http://www.wikidata.org/entity/Q30'), ('label', 'United States of America')]
# [('object', 'http://www.wikidata.org/entity/Q31'), ('label', 'Belgium')]
# [('object', 'http://www.wikidata.org/entity/Q32'), ('label', 'Luxembourg')]
# [('object', 'http://www.wikidata.org/entity/Q33'), ('label', 'Finland')]
# [('object', 'http://www.wikidata.org/entity/Q34'), ('label', 'Sweden')]
# [('object', 'http://www.wikidata.org/entity/Q35'), ('label', 'Denmark')]
# [('object', 'http://www.wikidata.org/entity/Q36'), ('label', 'Poland')]
# [('object', 'http://www.wikidata.org/entity/Q36704'), ('label', 'Yugoslavia')]
# [('object', 'http://www.wikidata.org/entity/Q38'), ('label', 'Italy')]
# [('object', 'http://www.wikidata.org/entity/Q39'), ('label', 'Switzerland')]
# [('object', 'http://www.wikidata.org/entity/Q40'), ('label', 'Austria')]
# [('object', 'http://www.wikidata.org/entity/Q403'), ('label', 'Serbia')]
# [('object', 'http://www.wikidata.org/entity/Q408'), ('label', 'Australia')]
# [('object', 'http://www.wikidata.org/entity/Q41'), ('label', 'Greece')]
# [('object', 'http://www.wikidata.org/entity/Q414'), ('label', 'Argentina')]
# [('object', 'http://www.wikidata.org/entity/Q419'), ('label', 'Peru')]
# [('object', 'http://www.wikidata.org/entity/Q43'), ('label', 'Turkey')]
# [('object', 'http://www.wikidata.org/entity/Q45'), ('label', 'Portugal')]
# [('object', 'http://www.wikidata.org/entity/Q55'), ('label', 'Netherlands')]
# [('object', 'http://www.wikidata.org/entity/Q664'), ('label', 'New Zealand')]
# [('object', 'http://www.wikidata.org/entity/Q668'), ('label', 'India')]
# [('object', 'http://www.wikidata.org/entity/Q691'), ('label', 'Papua New Guinea')]
# [('object', 'http://www.wikidata.org/entity/Q733'), ('label', 'Paraguay')]
# [('object', 'http://www.wikidata.org/entity/Q739'), ('label', 'Colombia')]
# [('object', 'http://www.wikidata.org/entity/Q766'), ('label', 'Jamaica')]
# [('object', 'http://www.wikidata.org/entity/Q77'), ('label', 'Uruguay')]
# [('object', 'http://www.wikidata.org/entity/Q79'), ('label', 'Egypt')]
# [('object', 'http://www.wikidata.org/entity/Q801'), ('label', 'Israel')]
# [('object', 'http://www.wikidata.org/entity/Q813'), ('label', 'Kyrgyzstan')]
# [('object', 'http://www.wikidata.org/entity/Q83286'), ('label', 'Socialist Federal Republic of Yugoslavia')]
# [('object', 'http://www.wikidata.org/entity/Q928'), ('label', 'Philippines')]
# [('object', 'http://www.wikidata.org/entity/Q948'), ('label', 'Tunisia')]
# [('object', 'http://www.wikidata.org/entity/Q96'), ('label', 'Mexico')]
# [('object', 'http://www.wikidata.org/entity/Q28513'), ('label', 'Austria-Hungary')]
# [('object', 'http://www.wikidata.org/entity/Q33946'), ('label', 'Czechoslovakia')]
# [('object', 'http://www.wikidata.org/entity/Q39193'), ('label', 'Bohemia')]
# [('object', 'http://www.wikidata.org/entity/Q1008'), ('label', 'Ivory Coast')]
# [('object', 'http://www.wikidata.org/entity/Q114'), ('label', 'Kenya')]
# [('object', 'http://www.wikidata.org/entity/Q1206012'), ('label', 'German Reich')]
# [('object', 'http://www.wikidata.org/entity/Q225'), ('label', 'Bosnia and Herzegovina')]
# [('object', 'http://www.wikidata.org/entity/Q298'), ('label', 'Chile')]
# [('object', 'http://www.wikidata.org/entity/Q34266'), ('label', 'Russian Empire')]
# [('object', 'http://www.wikidata.org/entity/Q713750'), ('label', 'West Germany')]
# [('object', 'http://www.wikidata.org/entity/Q717'), ('label', 'Venezuela')]
# [('object', 'http://www.wikidata.org/entity/Q790'), ('label', 'Haiti')]
# [('object', 'http://www.wikidata.org/entity/Q792'), ('label', 'El Salvador')]
# [('object', 'http://www.wikidata.org/entity/Q884'), ('label', 'South Korea')]
# [('object', 'http://www.wikidata.org/entity/Q953'), ('label', 'Zambia')]
# [('object', 'http://www.wikidata.org/entity/Q217169'), ('label', 'Rhodesia')]
# [('object', 'http://www.wikidata.org/entity/Q1000'), ('label', 'Gabon')]
# [('object', 'http://www.wikidata.org/entity/Q117'), ('label', 'Ghana')]
# [('object', 'http://www.wikidata.org/entity/Q133356'), ('label', 'Ukrainian Soviet Socialist Republic')]
# [('object', 'http://www.wikidata.org/entity/Q189'), ('label', 'Iceland')]
# [('object', 'http://www.wikidata.org/entity/Q235'), ('label', 'Monaco')]
# [('object', 'http://www.wikidata.org/entity/Q238'), ('label', 'San Marino')]
# [('object', 'http://www.wikidata.org/entity/Q25'), ('label', 'Wales')]
# [('object', 'http://www.wikidata.org/entity/Q334'), ('label', 'Singapore')]
# [('object', 'http://www.wikidata.org/entity/Q37'), ('label', 'Lithuania')]
# [('object', 'http://www.wikidata.org/entity/Q736'), ('label', 'Ecuador')]
# [('object', 'http://www.wikidata.org/entity/Q783'), ('label', 'Honduras')]
# [('object', 'http://www.wikidata.org/entity/Q1028'), ('label', 'Morocco')]
# [('object', 'http://www.wikidata.org/entity/Q1183'), ('label', 'Puerto Rico')]
# [('object', 'http://www.wikidata.org/entity/Q228'), ('label', 'Andorra')]
# [('object', 'http://www.wikidata.org/entity/Q750'), ('label', 'Bolivia')]
# [('object', 'http://www.wikidata.org/entity/Q858'), ('label', 'Syria')]
# [('object', 'http://www.wikidata.org/entity/Q8646'), ('label', 'Hong Kong')]
# [('object', 'http://www.wikidata.org/entity/Q954'), ('label', 'Zimbabwe')]
# [('object', 'http://www.wikidata.org/entity/Q191077'), ('label', 'Kingdom of Yugoslavia')]
# [('object', 'http://www.wikidata.org/entity/Q21203'), ('label', 'Aruba')]
# [('object', 'http://www.wikidata.org/entity/Q23635'), ('label', 'Bermuda')]
# [('object', 'http://www.wikidata.org/entity/Q265'), ('label', 'Uzbekistan')]
# [('object', 'http://www.wikidata.org/entity/Q398'), ('label', 'Bahrain')]
# [('object', 'http://www.wikidata.org/entity/Q854'), ('label', 'Sri Lanka')]
# [('object', 'http://www.wikidata.org/entity/Q865'), ('label', 'Taiwan')]
# [('object', 'http://www.wikidata.org/entity/Q2670092'), ('label', 'Dominion of Ceylon')]
# [('object', 'http://www.wikidata.org/entity/Q185573'), ('label', 'Czech lands')]
# [('object', 'http://www.wikidata.org/entity/Q833'), ('label', 'Malaysia')]
# [('object', 'http://www.wikidata.org/entity/Q962'), ('label', 'Benin')]
# 116

# %%
# getting all players that won an edition of 'australian open'
queryString = """
SELECT ?player ?label_player
WHERE
{
    # ?player wdt:P106 wd:Q10833314.
    # ?player wdt:P2522 ?victory.
    
    FILTER (?victory = ?eventWise_edition_of_grand_slam)
    
    # ?player sc:name ?label_player.
    {
        SELECT DISTINCT ?eventWise_edition_of_grand_slam ?label
        WHERE
        {
           # ?yearWise_edition_of_grand_slam wdt:P31 wd:Q60874.
           # ?eventWise_edition_of_grand_slam wdt:P361 ?yearWise_edition_of_grand_slam.

           # ?eventWise_edition_of_grand_slam sc:name ?label.
        }
    }
}
GROUP BY ?player ?label_player 
LIMIT 50
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('player', 'http://www.wikidata.org/entity/Q10118'), ('label_player', 'Victoria Azarenka')]
# [('player', 'http://www.wikidata.org/entity/Q84079953'), ('label_player', 'Nicholas David Ionel')]
# [('player', 'http://www.wikidata.org/entity/Q53424'), ('label_player', 'Shirley Fry')]
# [('player', 'http://www.wikidata.org/entity/Q53390'), ('label_player', 'Maureen Connolly')]
# [('player', 'http://www.wikidata.org/entity/Q54527'), ('label_player', 'Billie Jean King')]
# [('player', 'http://www.wikidata.org/entity/Q131120'), ('label_player', 'Anna Kournikova')]
# [('player', 'http://www.wikidata.org/entity/Q17466583'), ('label_player', 'Naomi Osaka')]
# [('player', 'http://www.wikidata.org/entity/Q202342'), ('label_player', 'Margaret Court')]
# [('player', 'http://www.wikidata.org/entity/Q54546'), ('label_player', 'Nancy Richey')]
# [('player', 'http://www.wikidata.org/entity/Q53338'), ('label_player', 'Louise Brough')]
# [('player', 'http://www.wikidata.org/entity/Q11677'), ('label_player', 'Lindsay Davenport')]
# [('player', 'http://www.wikidata.org/entity/Q53564'), ('label_player', 'Doris Hart')]
# [('player', 'http://www.wikidata.org/entity/Q48351'), ('label_player', 'Dorothy Round')]
# [('player', 'http://www.wikidata.org/entity/Q1426'), ('label_player', 'Roger Federer')]
# 14

# %%
# getting all players that won an edition of 'french open'
queryString = """
SELECT ?player ?label_player 
WHERE
{
    # ?player wdt:P106 wd:Q10833314.
    # ?player wdt:P2522 ?victory.
    
    FILTER (?victory = ?eventWise_edition_of_grand_slam)
    
    # ?player sc:name ?label_player.
    {
        SELECT DISTINCT ?eventWise_edition_of_grand_slam ?label
        WHERE
        {
           # ?yearWise_edition_of_grand_slam wdt:P31 wd:Q43605.
           # ?eventWise_edition_of_grand_slam wdt:P361 ?yearWise_edition_of_grand_slam.

           # ?eventWise_edition_of_grand_slam sc:name ?label.
        }
    }
}
GROUP BY ?player ?label_player 
LIMIT 50
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('player', 'http://www.wikidata.org/entity/Q106354932'), ('label_player', 'Linda Nosková')]
# [('player', 'http://www.wikidata.org/entity/Q53424'), ('label_player', 'Shirley Fry')]
# [('player', 'http://www.wikidata.org/entity/Q53390'), ('label_player', 'Maureen Connolly')]
# [('player', 'http://www.wikidata.org/entity/Q54543'), ('label_player', 'Helen Wills')]
# [('player', 'http://www.wikidata.org/entity/Q54527'), ('label_player', 'Billie Jean King')]
# [('player', 'http://www.wikidata.org/entity/Q11581'), ('label_player', 'Andrea Sestini Hlaváčková')]
# [('player', 'http://www.wikidata.org/entity/Q53550'), ('label_player', 'Althea Gibson')]
# [('player', 'http://www.wikidata.org/entity/Q106113'), ('label_player', 'Ilie Năstase')]
# [('player', 'http://www.wikidata.org/entity/Q202342'), ('label_player', 'Margaret Court')]
# [('player', 'http://www.wikidata.org/entity/Q1144091'), ('label_player', 'Hank Pfister')]
# [('player', 'http://www.wikidata.org/entity/Q54546'), ('label_player', 'Nancy Richey')]
# [('player', 'http://www.wikidata.org/entity/Q259356'), ('label_player', 'Ann Haydon-Jones')]
# [('player', 'http://www.wikidata.org/entity/Q112821'), ('label_player', 'Jim Grabb')]
# [('player', 'http://www.wikidata.org/entity/Q53562'), ('label_player', 'Darlene Hard')]
# [('player', 'http://www.wikidata.org/entity/Q11662'), ('label_player', 'Steffi Graf')]
# [('player', 'http://www.wikidata.org/entity/Q132147'), ('label_player', 'Sania Mirza')]
# [('player', 'http://www.wikidata.org/entity/Q375938'), ('label_player', 'Adriano Panatta')]
# [('player', 'http://www.wikidata.org/entity/Q230156'), ('label_player', 'Simona Halep')]
# [('player', 'http://www.wikidata.org/entity/Q11680'), ('label_player', 'Jennifer Capriati')]
# [('player', 'http://www.wikidata.org/entity/Q53564'), ('label_player', 'Doris Hart')]
# [('player', 'http://www.wikidata.org/entity/Q11578'), ('label_player', 'Venus Williams')]
# [('player', 'http://www.wikidata.org/entity/Q26840238'), ('label_player', 'Iga Świątek')]
# [('player', 'http://www.wikidata.org/entity/Q34276'), ('label_player', 'Garbiñe Muguruza')]
# [('player', 'http://www.wikidata.org/entity/Q1426'), ('label_player', 'Roger Federer')]
# [('player', 'http://www.wikidata.org/entity/Q190723'), ('label_player', 'Gustavo Kuerten')]
# 25

# %%
# getting all players that won an edition of 'wimbledon championships'
queryString = """
SELECT ?player ?label_player
WHERE
{
    # ?player wdt:P106 wd:Q10833314.
    # ?player wdt:P2522 ?victory.
    
    FILTER (?victory = ?eventWise_edition_of_grand_slam)
    
    # ?player sc:name ?label_player.
    {
        SELECT DISTINCT ?eventWise_edition_of_grand_slam ?label
        WHERE
        {
           # ?yearWise_edition_of_grand_slam wdt:P31 wd:Q41520.
           # ?eventWise_edition_of_grand_slam wdt:P361 ?yearWise_edition_of_grand_slam.

           # ?eventWise_edition_of_grand_slam sc:name ?label.
        }
    }
}
GROUP BY ?player ?label_player 
LIMIT 50
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('player', 'http://www.wikidata.org/entity/Q10125'), ('label_player', 'Andy Murray')]
# [('player', 'http://www.wikidata.org/entity/Q233247'), ('label_player', 'Maria Bueno')]
# [('player', 'http://www.wikidata.org/entity/Q233234'), ('label_player', 'Virginia Wade')]
# [('player', 'http://www.wikidata.org/entity/Q53424'), ('label_player', 'Shirley Fry')]
# [('player', 'http://www.wikidata.org/entity/Q53390'), ('label_player', 'Maureen Connolly')]
# [('player', 'http://www.wikidata.org/entity/Q54543'), ('label_player', 'Helen Wills')]
# [('player', 'http://www.wikidata.org/entity/Q54527'), ('label_player', 'Billie Jean King')]
# [('player', 'http://www.wikidata.org/entity/Q53550'), ('label_player', 'Althea Gibson')]
# [('player', 'http://www.wikidata.org/entity/Q105550'), ('label_player', 'Rod Laver')]
# [('player', 'http://www.wikidata.org/entity/Q202342'), ('label_player', 'Margaret Court')]
# [('player', 'http://www.wikidata.org/entity/Q53567'), ('label_player', 'Helen Jacobs')]
# [('player', 'http://www.wikidata.org/entity/Q445602'), ('label_player', 'Manuel Santana')]
# [('player', 'http://www.wikidata.org/entity/Q259356'), ('label_player', 'Ann Haydon-Jones')]
# [('player', 'http://www.wikidata.org/entity/Q53338'), ('label_player', 'Louise Brough')]
# [('player', 'http://www.wikidata.org/entity/Q230156'), ('label_player', 'Simona Halep')]
# [('player', 'http://www.wikidata.org/entity/Q53564'), ('label_player', 'Doris Hart')]
# [('player', 'http://www.wikidata.org/entity/Q26840238'), ('label_player', 'Iga Świątek')]
# [('player', 'http://www.wikidata.org/entity/Q48351'), ('label_player', 'Dorothy Round')]
# [('player', 'http://www.wikidata.org/entity/Q34276'), ('label_player', 'Garbiñe Muguruza')]
# [('player', 'http://www.wikidata.org/entity/Q1426'), ('label_player', 'Roger Federer')]
# [('player', 'http://www.wikidata.org/entity/Q54535'), ('label_player', 'Alice Marble')]
# [('player', 'http://www.wikidata.org/entity/Q53331'), ('label_player', 'Pauline Betz')]
# 22

# %%
# getting all players that won an edition of 'US open'
queryString = """
SELECT ?player ?label_player
WHERE
{
    # ?player wdt:P106 wd:Q10833314.
    # ?player wdt:P2522 ?victory.
    
    FILTER (?victory = ?eventWise_edition_of_grand_slam)
    
    # ?player sc:name ?label_player.
    {
        SELECT DISTINCT ?eventWise_edition_of_grand_slam ?label
        WHERE
        {
           # ?yearWise_edition_of_grand_slam wdt:P31 wd:Q123577.
           # ?eventWise_edition_of_grand_slam wdt:P361 ?yearWise_edition_of_grand_slam.

           # ?eventWise_edition_of_grand_slam sc:name ?label.
        }
    }
}
GROUP BY ?player ?label_player 
LIMIT 50
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('player', 'http://www.wikidata.org/entity/Q10125'), ('label_player', 'Andy Murray')]
# [('player', 'http://www.wikidata.org/entity/Q233247'), ('label_player', 'Maria Bueno')]
# [('player', 'http://www.wikidata.org/entity/Q53424'), ('label_player', 'Shirley Fry')]
# [('player', 'http://www.wikidata.org/entity/Q53390'), ('label_player', 'Maureen Connolly')]
# [('player', 'http://www.wikidata.org/entity/Q54543'), ('label_player', 'Helen Wills')]
# [('player', 'http://www.wikidata.org/entity/Q54527'), ('label_player', 'Billie Jean King')]
# [('player', 'http://www.wikidata.org/entity/Q53550'), ('label_player', 'Althea Gibson')]
# [('player', 'http://www.wikidata.org/entity/Q106113'), ('label_player', 'Ilie Năstase')]
# [('player', 'http://www.wikidata.org/entity/Q17466583'), ('label_player', 'Naomi Osaka')]
# [('player', 'http://www.wikidata.org/entity/Q202342'), ('label_player', 'Margaret Court')]
# [('player', 'http://www.wikidata.org/entity/Q53567'), ('label_player', 'Helen Jacobs')]
# [('player', 'http://www.wikidata.org/entity/Q445602'), ('label_player', 'Manuel Santana')]
# [('player', 'http://www.wikidata.org/entity/Q112821'), ('label_player', 'Jim Grabb')]
# [('player', 'http://www.wikidata.org/entity/Q2093033'), ('label_player', 'Pierre-Hugues Herbert')]
# [('player', 'http://www.wikidata.org/entity/Q53562'), ('label_player', 'Darlene Hard')]
# [('player', 'http://www.wikidata.org/entity/Q53338'), ('label_player', 'Louise Brough')]
# [('player', 'http://www.wikidata.org/entity/Q53564'), ('label_player', 'Doris Hart')]
# [('player', 'http://www.wikidata.org/entity/Q1426'), ('label_player', 'Roger Federer')]
# [('player', 'http://www.wikidata.org/entity/Q54535'), ('label_player', 'Alice Marble')]
# [('player', 'http://www.wikidata.org/entity/Q53331'), ('label_player', 'Pauline Betz')]
# 20

# %%
# getting all tennis players that won an edition of each grand slam
queryString = """
SELECT * 
WHERE
{ 
    {
        SELECT ?player ?label_player 
        WHERE
        {
            # ?player wdt:P106 wd:Q10833314.
            # ?player wdt:P2522 ?victory.

            FILTER (?victory = ?eventWise_edition_of_grand_slam)

            # ?player sc:name ?label_player.
            {
                SELECT DISTINCT ?eventWise_edition_of_grand_slam ?label
                WHERE
                {
                   # ?yearWise_edition_of_grand_slam wdt:P31 wd:Q60874.
                   # ?eventWise_edition_of_grand_slam wdt:P361 ?yearWise_edition_of_grand_slam.

                   # ?eventWise_edition_of_grand_slam sc:name ?label.
                }
            }
        }
        GROUP BY ?player ?label_player 
    }
    UNION
    {
        SELECT ?player ?label_player
        WHERE
        {
            # ?player wdt:P106 wd:Q10833314.
            # ?player wdt:P2522 ?victory.

            FILTER (?victory = ?eventWise_edition_of_grand_slam)

            # ?player sc:name ?label_player.
            {
                SELECT DISTINCT ?eventWise_edition_of_grand_slam ?label
                WHERE
                {
                   # ?yearWise_edition_of_grand_slam wdt:P31 wd:Q43605.
                   # ?eventWise_edition_of_grand_slam wdt:P361 ?yearWise_edition_of_grand_slam.

                   # ?eventWise_edition_of_grand_slam sc:name ?label.
                }
            }
        }
        GROUP BY ?player ?label_player 
    }
    UNION
    {
        SELECT ?player ?label_player 
        WHERE
        {
            # ?player wdt:P106 wd:Q10833314.
            # ?player wdt:P2522 ?victory.

            FILTER (?victory = ?eventWise_edition_of_grand_slam)

            # ?player sc:name ?label_player.
            {
                SELECT DISTINCT ?eventWise_edition_of_grand_slam ?label
                WHERE
                {
                   # ?yearWise_edition_of_grand_slam wdt:P31 wd:Q41520.
                   # ?eventWise_edition_of_grand_slam wdt:P361 ?yearWise_edition_of_grand_slam.

                   # ?eventWise_edition_of_grand_slam sc:name ?label.
                }
            }
        }
        GROUP BY ?player ?label_player 
    }
    UNION
    {
        SELECT DISTINCT ?player ?label_player
        WHERE
        {
            # ?player wdt:P106 wd:Q10833314.
            # ?player wdt:P2522 ?victory.

            FILTER (?victory = ?eventWise_edition_of_grand_slam)

            # ?player sc:name ?label_player.
            {
                SELECT DISTINCT ?eventWise_edition_of_grand_slam ?label
                WHERE
                {
                   # ?yearWise_edition_of_grand_slam wdt:P31 wd:Q123577.
                   # ?eventWise_edition_of_grand_slam wdt:P361 ?yearWise_edition_of_grand_slam.

                   # ?eventWise_edition_of_grand_slam sc:name ?label.
                }
            }
        }
        GROUP BY ?player ?label_player 
    }
}
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('player', 'http://www.wikidata.org/entity/Q54546'), ('label_player', 'Nancy Richey')]
# [('player', 'http://www.wikidata.org/entity/Q202342'), ('label_player', 'Margaret Court')]
# [('player', 'http://www.wikidata.org/entity/Q10118'), ('label_player', 'Victoria Azarenka')]
# [('player', 'http://www.wikidata.org/entity/Q53424'), ('label_player', 'Shirley Fry')]
# [('player', 'http://www.wikidata.org/entity/Q53390'), ('label_player', 'Maureen Connolly')]
# [('player', 'http://www.wikidata.org/entity/Q53564'), ('label_player', 'Doris Hart')]
# [('player', 'http://www.wikidata.org/entity/Q131120'), ('label_player', 'Anna Kournikova')]
# [('player', 'http://www.wikidata.org/entity/Q1426'), ('label_player', 'Roger Federer')]
# [('player', 'http://www.wikidata.org/entity/Q54527'), ('label_player', 'Billie Jean King')]
# [('player', 'http://www.wikidata.org/entity/Q53338'), ('label_player', 'Louise Brough')]
# [('player', 'http://www.wikidata.org/entity/Q11677'), ('label_player', 'Lindsay Davenport')]
# [('player', 'http://www.wikidata.org/entity/Q17466583'), ('label_player', 'Naomi Osaka')]
# [('player', 'http://www.wikidata.org/entity/Q48351'), ('label_player', 'Dorothy Round')]
# [('player', 'http://www.wikidata.org/entity/Q84079953'), ('label_player', 'Nicholas David Ionel')]
# [('player', 'http://www.wikidata.org/entity/Q54546'), ('label_player', 'Nancy Richey')]
# [('player', 'http://www.wikidata.org/entity/Q202342'), ('label_player', 'Margaret Court')]
# [('player', 'http://www.wikidata.org/entity/Q53550'), ('label_player', 'Althea Gibson')]
# [('player', 'http://www.wikidata.org/entity/Q53424'), ('label_player', 'Shirley Fry')]
# [('player', 'http://www.wikidata.org/entity/Q259356'), ('label_player', 'Ann Haydon-Jones')]
# [('player', 'http://www.wikidata.org/entity/Q11662'), ('label_player', 'Steffi Graf')]
# [('player', 'http://www.wikidata.org/entity/Q53390'), ('label_player', 'Maureen Connolly')]
# [('player', 'http://www.wikidata.org/entity/Q53564'), ('label_player', 'Doris Hart')]
# [('player', 'http://www.wikidata.org/entity/Q132147'), ('label_player', 'Sania Mirza')]
# [('player', 'http://www.wikidata.org/entity/Q54543'), ('label_player', 'Helen Wills')]
# [('player', 'http://www.wikidata.org/entity/Q375938'), ('label_player', 'Adriano Panatta')]
# [('player', 'http://www.wikidata.org/entity/Q34276'), ('label_player', 'Garbiñe Muguruza')]
# [('player', 'http://www.wikidata.org/entity/Q106113'), ('label_player', 'Ilie Năstase')]
# [('player', 'http://www.wikidata.org/entity/Q1426'), ('label_player', 'Roger Federer')]
# [('player', 'http://www.wikidata.org/entity/Q230156'), ('label_player', 'Simona Halep')]
# [('player', 'http://www.wikidata.org/entity/Q54527'), ('label_player', 'Billie Jean King')]
# [('player', 'http://www.wikidata.org/entity/Q112821'), ('label_player', 'Jim Grabb')]
# [('player', 'http://www.wikidata.org/entity/Q11680'), ('label_player', 'Jennifer Capriati')]
# [('player', 'http://www.wikidata.org/entity/Q11578'), ('label_player', 'Venus Williams')]
# [('player', 'http://www.wikidata.org/entity/Q190723'), ('label_player', 'Gustavo Kuerten')]
# [('player', 'http://www.wikidata.org/entity/Q11581'), ('label_player', 'Andrea Sestini Hlaváčková')]
# [('player', 'http://www.wikidata.org/entity/Q26840238'), ('label_player', 'Iga Świątek')]
# [('player', 'http://www.wikidata.org/entity/Q53562'), ('label_player', 'Darlene Hard')]
# [('player', 'http://www.wikidata.org/entity/Q1144091'), ('label_player', 'Hank Pfister')]
# [('player', 'http://www.wikidata.org/entity/Q106354932'), ('label_player', 'Linda Nosková')]
# [('player', 'http://www.wikidata.org/entity/Q445602'), ('label_player', 'Manuel Santana')]
# [('player', 'http://www.wikidata.org/entity/Q202342'), ('label_player', 'Margaret Court')]
# [('player', 'http://www.wikidata.org/entity/Q233234'), ('label_player', 'Virginia Wade')]
# [('player', 'http://www.wikidata.org/entity/Q53550'), ('label_player', 'Althea Gibson')]
# [('player', 'http://www.wikidata.org/entity/Q53424'), ('label_player', 'Shirley Fry')]
# [('player', 'http://www.wikidata.org/entity/Q259356'), ('label_player', 'Ann Haydon-Jones')]
# [('player', 'http://www.wikidata.org/entity/Q53390'), ('label_player', 'Maureen Connolly')]
# [('player', 'http://www.wikidata.org/entity/Q53564'), ('label_player', 'Doris Hart')]
# [('player', 'http://www.wikidata.org/entity/Q54543'), ('label_player', 'Helen Wills')]
# [('player', 'http://www.wikidata.org/entity/Q34276'), ('label_player', 'Garbiñe Muguruza')]
# [('player', 'http://www.wikidata.org/entity/Q1426'), ('label_player', 'Roger Federer')]
# [('player', 'http://www.wikidata.org/entity/Q105550'), ('label_player', 'Rod Laver')]
# [('player', 'http://www.wikidata.org/entity/Q230156'), ('label_player', 'Simona Halep')]
# [('player', 'http://www.wikidata.org/entity/Q54527'), ('label_player', 'Billie Jean King')]
# [('player', 'http://www.wikidata.org/entity/Q54535'), ('label_player', 'Alice Marble')]
# [('player', 'http://www.wikidata.org/entity/Q10125'), ('label_player', 'Andy Murray')]
# [('player', 'http://www.wikidata.org/entity/Q53338'), ('label_player', 'Louise Brough')]
# [('player', 'http://www.wikidata.org/entity/Q26840238'), ('label_player', 'Iga Świątek')]
# [('player', 'http://www.wikidata.org/entity/Q233247'), ('label_player', 'Maria Bueno')]
# [('player', 'http://www.wikidata.org/entity/Q53567'), ('label_player', 'Helen Jacobs')]
# [('player', 'http://www.wikidata.org/entity/Q53331'), ('label_player', 'Pauline Betz')]
# [('player', 'http://www.wikidata.org/entity/Q48351'), ('label_player', 'Dorothy Round')]
# [('player', 'http://www.wikidata.org/entity/Q10125'), ('label_player', 'Andy Murray')]
# [('player', 'http://www.wikidata.org/entity/Q233247'), ('label_player', 'Maria Bueno')]
# [('player', 'http://www.wikidata.org/entity/Q53424'), ('label_player', 'Shirley Fry')]
# [('player', 'http://www.wikidata.org/entity/Q53390'), ('label_player', 'Maureen Connolly')]
# [('player', 'http://www.wikidata.org/entity/Q54543'), ('label_player', 'Helen Wills')]
# [('player', 'http://www.wikidata.org/entity/Q54527'), ('label_player', 'Billie Jean King')]
# [('player', 'http://www.wikidata.org/entity/Q53550'), ('label_player', 'Althea Gibson')]
# [('player', 'http://www.wikidata.org/entity/Q106113'), ('label_player', 'Ilie Năstase')]
# [('player', 'http://www.wikidata.org/entity/Q17466583'), ('label_player', 'Naomi Osaka')]
# [('player', 'http://www.wikidata.org/entity/Q202342'), ('label_player', 'Margaret Court')]
# [('player', 'http://www.wikidata.org/entity/Q53567'), ('label_player', 'Helen Jacobs')]
# [('player', 'http://www.wikidata.org/entity/Q445602'), ('label_player', 'Manuel Santana')]
# [('player', 'http://www.wikidata.org/entity/Q112821'), ('label_player', 'Jim Grabb')]
# [('player', 'http://www.wikidata.org/entity/Q2093033'), ('label_player', 'Pierre-Hugues Herbert')]
# [('player', 'http://www.wikidata.org/entity/Q53562'), ('label_player', 'Darlene Hard')]
# [('player', 'http://www.wikidata.org/entity/Q53338'), ('label_player', 'Louise Brough')]
# [('player', 'http://www.wikidata.org/entity/Q53564'), ('label_player', 'Doris Hart')]
# [('player', 'http://www.wikidata.org/entity/Q1426'), ('label_player', 'Roger Federer')]
# [('player', 'http://www.wikidata.org/entity/Q54535'), ('label_player', 'Alice Marble')]
# [('player', 'http://www.wikidata.org/entity/Q53331'), ('label_player', 'Pauline Betz')]
# 81

# %%
# getting the players from last query that has been reported 4 times meaning
# that they have won at least one edition of each grand slam

# to me at least one edition of EACH grand slam means that a player who has won at least once in ALL 4 grand slams
queryString = """
SELECT ?player ?label_player (COUNT (*) AS ?count)
WHERE
{ 
    {
        SELECT ?player ?label_player
        WHERE
        {
            # ?player wdt:P106 wd:Q10833314.
            # ?player wdt:P2522 ?victory.

            FILTER (?victory = ?eventWise_edition_of_grand_slam)

            # ?player sc:name ?label_player.
            {
                SELECT DISTINCT ?eventWise_edition_of_grand_slam ?label
                WHERE
                {
                   # ?yearWise_edition_of_grand_slam wdt:P31 wd:Q60874.
                   # ?eventWise_edition_of_grand_slam wdt:P361 ?yearWise_edition_of_grand_slam.

                   # ?eventWise_edition_of_grand_slam sc:name ?label.
                }
            }
        }
        GROUP BY ?player ?label_player 
    }
    UNION
    {
        SELECT ?player ?label_player 
        WHERE
        {
            # ?player wdt:P106 wd:Q10833314.
            # ?player wdt:P2522 ?victory.

            FILTER (?victory = ?eventWise_edition_of_grand_slam)

            # ?player sc:name ?label_player.
            {
                SELECT DISTINCT ?eventWise_edition_of_grand_slam ?label
                WHERE
                {
                   # ?yearWise_edition_of_grand_slam wdt:P31 wd:Q43605.
                   # ?eventWise_edition_of_grand_slam wdt:P361 ?yearWise_edition_of_grand_slam.

                   # ?eventWise_edition_of_grand_slam sc:name ?label.
                }
            }
        }
        GROUP BY ?player ?label_player 
    }
    UNION
    {
        SELECT ?player ?label_player
        WHERE
        {
            # ?player wdt:P106 wd:Q10833314.
            # ?player wdt:P2522 ?victory.

            FILTER (?victory = ?eventWise_edition_of_grand_slam)

            # ?player sc:name ?label_player.
            {
                SELECT DISTINCT ?eventWise_edition_of_grand_slam ?label
                WHERE
                {
                   # ?yearWise_edition_of_grand_slam wdt:P31 wd:Q41520.
                   # ?eventWise_edition_of_grand_slam wdt:P361 ?yearWise_edition_of_grand_slam.

                   # ?eventWise_edition_of_grand_slam sc:name ?label.
                }
            }
        }
        GROUP BY ?player ?label_player 
    }
    UNION
    {
        SELECT DISTINCT ?player ?label_player
        WHERE
        {
            # ?player wdt:P106 wd:Q10833314.
            # ?player wdt:P2522 ?victory.

            FILTER (?victory = ?eventWise_edition_of_grand_slam)

            # ?player sc:name ?label_player.
            {
                SELECT DISTINCT ?eventWise_edition_of_grand_slam ?label
                WHERE
                {
                   # ?yearWise_edition_of_grand_slam wdt:P31 wd:Q123577.
                   # ?eventWise_edition_of_grand_slam wdt:P361 ?yearWise_edition_of_grand_slam.

                   # ?eventWise_edition_of_grand_slam sc:name ?label.
                }
            }
        }
        GROUP BY ?player ?label_player 
    }
}
GROUP BY ?player ?label_player
HAVING (COUNT(*) = 4)
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('player', 'http://www.wikidata.org/entity/Q53424'), ('label_player', 'Shirley Fry'), ('count', '4')]
# [('player', 'http://www.wikidata.org/entity/Q53390'), ('label_player', 'Maureen Connolly'), ('count', '4')]
# [('player', 'http://www.wikidata.org/entity/Q54527'), ('label_player', 'Billie Jean King'), ('count', '4')]
# [('player', 'http://www.wikidata.org/entity/Q202342'), ('label_player', 'Margaret Court'), ('count', '4')]
# [('player', 'http://www.wikidata.org/entity/Q53564'), ('label_player', 'Doris Hart'), ('count', '4')]
# [('player', 'http://www.wikidata.org/entity/Q1426'), ('label_player', 'Roger Federer'), ('count', '4')]
# 6

# %%
# checking 'country for sport' property of node 'Margaret Court'

# the reason for checking this query was that when I included ?player wdt:P1532 ?country in the last query's
# clauses, it affected the output results and I did not get 'Margaret Court' as an answer. The snapshot seems  
# again a bit problematic because P1532 actually exists for 'Margaret Court' on wikidata online
queryString = """
SELECT ?object ?label
WHERE
{
   wd:Q202342 wdt:P1532 ?object.
   
   # ?object sc:name ?label.
}
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# Empty

# %% [markdown]
# Final query for this task

# %%
# write your final query

# as in the last query, after using P1532 property, 'Margaret Court' gets excluded from the result set because
# of the mentioned problem and so, country 'australia' is not shown in the final output
queryString = """
SELECT DISTINCT ?country ?label
WHERE
{
    # ?player wdt:P1532 ?country.
    
    # ?country sc:name ?label.
    {
        SELECT ?player ?label_player (COUNT (*) AS ?count)
        WHERE
        { 
            {
                SELECT ?player ?label_player
                WHERE
                {
                    # ?player wdt:P106 wd:Q10833314.
                    # ?player wdt:P2522 ?victory.

                    FILTER (?victory = ?eventWise_edition_of_grand_slam)

                    # ?player sc:name ?label_player.
                    {
                        SELECT DISTINCT ?eventWise_edition_of_grand_slam ?label
                        WHERE
                        {
                           # ?yearWise_edition_of_grand_slam wdt:P31 wd:Q60874.
                           # ?eventWise_edition_of_grand_slam wdt:P361 ?yearWise_edition_of_grand_slam.

                           # ?eventWise_edition_of_grand_slam sc:name ?label.
                        }
                    }
                }
                GROUP BY ?player ?label_player 
            }
            UNION
            {
                SELECT ?player ?label_player
                WHERE
                {
                    # ?player wdt:P106 wd:Q10833314.
                    # ?player wdt:P2522 ?victory.

                    FILTER (?victory = ?eventWise_edition_of_grand_slam)

                    # ?player sc:name ?label_player.
                    {
                        SELECT DISTINCT ?eventWise_edition_of_grand_slam ?label
                        WHERE
                        {
                           # ?yearWise_edition_of_grand_slam wdt:P31 wd:Q43605.
                           # ?eventWise_edition_of_grand_slam wdt:P361 ?yearWise_edition_of_grand_slam.

                           # ?eventWise_edition_of_grand_slam sc:name ?label.
                        }
                    }
                }
                GROUP BY ?player ?label_player 
            }
            UNION
            {
                SELECT ?player ?label_player
                WHERE
                {
                    # ?player wdt:P106 wd:Q10833314.
                    # ?player wdt:P2522 ?victory.

                    FILTER (?victory = ?eventWise_edition_of_grand_slam)

                    # ?player sc:name ?label_player.
                    {
                        SELECT DISTINCT ?eventWise_edition_of_grand_slam ?label
                        WHERE
                        {
                           # ?yearWise_edition_of_grand_slam wdt:P31 wd:Q41520.
                           # ?eventWise_edition_of_grand_slam wdt:P361 ?yearWise_edition_of_grand_slam.

                           # ?eventWise_edition_of_grand_slam sc:name ?label.
                        }
                    }
                }
                GROUP BY ?player ?label_player 
            }
            UNION
            {
                SELECT DISTINCT ?player ?label_player
                WHERE
                {
                    # ?player wdt:P106 wd:Q10833314.
                    # ?player wdt:P2522 ?victory.

                    FILTER (?victory = ?eventWise_edition_of_grand_slam)

                    # ?player sc:name ?label_player.
                    {
                        SELECT DISTINCT ?eventWise_edition_of_grand_slam ?label
                        WHERE
                        {
                           # ?yearWise_edition_of_grand_slam wdt:P31 wd:Q123577.
                           # ?eventWise_edition_of_grand_slam wdt:P361 ?yearWise_edition_of_grand_slam.

                           # ?eventWise_edition_of_grand_slam sc:name ?label.
                        }
                    }
                }
                GROUP BY ?player ?label_player 
            }
        }
        GROUP BY ?player ?label_player
        HAVING (COUNT(*) = 4)
    }
}
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('country', 'http://www.wikidata.org/entity/Q30'), ('label', 'United States of America')]
# [('country', 'http://www.wikidata.org/entity/Q39'), ('label', 'Switzerland')]
# 2

# %% [markdown]
# ## Task 8
# Consider the country for sport property of the tennis player (NO Country of citizenship). Return the countries with at least one player who was ranked 1 in the tennis ranking  (the result set must be a list of country IRI and label).

# %%
# write your queries
# checking the 'ranking' property of node 'Roger Federer' to see if is 1
queryString = """
SELECT ?object
WHERE
{
   wd:Q1426 wdt:P1352 ?object.

   FILTER (datatype(?object) = xsd:int)
   FILTER("1"^^xsd:int = ?object)
}
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('object', '1')]
# 1

# %%
# getting all the players who ranked 1
queryString = """
SELECT ?player ?label ?ranking
WHERE
{
   # ?player wdt:P106 wd:Q10833314.
   # ?player wdt:P1352 ?ranking.

   FILTER (datatype(?ranking) = xsd:int)
   FILTER("1"^^xsd:int = ?ranking)
   
   # ?player sc:name ?label.
}
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('player', 'http://www.wikidata.org/entity/Q207352'), ('label', 'Agnieszka Radwańska'), ('ranking', '1')]
# [('player', 'http://www.wikidata.org/entity/Q455136'), ('label', 'Anders Järryd'), ('ranking', '1')]
# [('player', 'http://www.wikidata.org/entity/Q455411'), ('label', 'Tom Okker'), ('ranking', '1')]
# [('player', 'http://www.wikidata.org/entity/Q310419'), ('label', 'Nenad Zimonjić'), ('ranking', '1')]
# [('player', 'http://www.wikidata.org/entity/Q53393'), ('label', 'Jimmy Connors'), ('ranking', '1')]
# [('player', 'http://www.wikidata.org/entity/Q10118'), ('label', 'Victoria Azarenka'), ('ranking', '1')]
# [('player', 'http://www.wikidata.org/entity/Q13538'), ('label', 'Henri Kontinen'), ('ranking', '1')]
# [('player', 'http://www.wikidata.org/entity/Q1743002'), ('label', 'Robert Seguso'), ('ranking', '1')]
# [('player', 'http://www.wikidata.org/entity/Q189542'), ('label', 'Stefan Edberg'), ('ranking', '1')]
# [('player', 'http://www.wikidata.org/entity/Q232566'), ('label', 'Hsieh Su-wei'), ('ranking', '1')]
# [('player', 'http://www.wikidata.org/entity/Q289365'), ('label', 'Karolína Plíšková'), ('ranking', '1')]
# [('player', 'http://www.wikidata.org/entity/Q30217670'), ('label', 'Whitney Osuigwe'), ('ranking', '1')]
# [('player', 'http://www.wikidata.org/entity/Q11662'), ('label', 'Steffi Graf'), ('ranking', '1')]
# [('player', 'http://www.wikidata.org/entity/Q182736'), ('label', 'Ivan Lendl'), ('ranking', '1')]
# [('player', 'http://www.wikidata.org/entity/Q54584'), ('label', 'Andy Roddick'), ('ranking', '1')]
# [('player', 'http://www.wikidata.org/entity/Q76334'), ('label', 'Boris Becker'), ('ranking', '1')]
# [('player', 'http://www.wikidata.org/entity/Q132147'), ('label', 'Sania Mirza'), ('ranking', '1')]
# [('player', 'http://www.wikidata.org/entity/Q229093'), ('label', 'Virginia Ruano Pascual'), ('ranking', '1')]
# [('player', 'http://www.wikidata.org/entity/Q487182'), ('label', 'Anastasia Pavlyuchenkova'), ('ranking', '1')]
# [('player', 'http://www.wikidata.org/entity/Q270414'), ('label', 'Anne Smith'), ('ranking', '1')]
# [('player', 'http://www.wikidata.org/entity/Q298542'), ('label', 'Daniel Nestor'), ('ranking', '1')]
# [('player', 'http://www.wikidata.org/entity/Q345626'), ('label', 'Łukasz Kubot'), ('ranking', '1')]
# [('player', 'http://www.wikidata.org/entity/Q134720'), ('label', 'Martina Hingis'), ('ranking', '1')]
# [('player', 'http://www.wikidata.org/entity/Q11685'), ('label', 'Kim Clijsters'), ('ranking', '1')]
# [('player', 'http://www.wikidata.org/entity/Q221908'), ('label', 'Yannick Noah'), ('ranking', '1')]
# [('player', 'http://www.wikidata.org/entity/Q229116'), ('label', 'Katarina Srebotnik'), ('ranking', '1')]
# [('player', 'http://www.wikidata.org/entity/Q634844'), ('label', 'Elena Vesnina'), ('ranking', '1')]
# [('player', 'http://www.wikidata.org/entity/Q180872'), ('label', 'Amélie Mauresmo'), ('ranking', '1')]
# [('player', 'http://www.wikidata.org/entity/Q34276'), ('label', 'Garbiñe Muguruza'), ('ranking', '1')]
# [('player', 'http://www.wikidata.org/entity/Q10129'), ('label', 'Lisa Raymond'), ('ranking', '1')]
# [('player', 'http://www.wikidata.org/entity/Q11459'), ('label', 'Serena Williams'), ('ranking', '1')]
# [('player', 'http://www.wikidata.org/entity/Q191766'), ('label', 'Samantha Stosur'), ('ranking', '1')]
# [('player', 'http://www.wikidata.org/entity/Q230815'), ('label', 'Rennae Stubbs'), ('ranking', '1')]
# [('player', 'http://www.wikidata.org/entity/Q104506'), ('label', 'Björn Borg'), ('ranking', '1')]
# [('player', 'http://www.wikidata.org/entity/Q53340'), ('label', 'Bob Bryan'), ('ranking', '1')]
# [('player', 'http://www.wikidata.org/entity/Q53342'), ('label', 'Mike Bryan'), ('ranking', '1')]
# [('player', 'http://www.wikidata.org/entity/Q229100'), ('label', 'Ai Sugiyama'), ('ranking', '1')]
# [('player', 'http://www.wikidata.org/entity/Q211428'), ('label', 'Kaia Kanepi'), ('ranking', '1')]
# [('player', 'http://www.wikidata.org/entity/Q234624'), ('label', 'Latisha Chan'), ('ranking', '1')]
# [('player', 'http://www.wikidata.org/entity/Q241320'), ('label', 'Julie Halard-Decugis'), ('ranking', '1')]
# [('player', 'http://www.wikidata.org/entity/Q95162'), ('label', 'Roberta Vinci'), ('ranking', '1')]
# [('player', 'http://www.wikidata.org/entity/Q921488'), ('label', 'Juan Sebastián Cabal'), ('ranking', '1')]
# [('player', 'http://www.wikidata.org/entity/Q131120'), ('label', 'Anna Kournikova'), ('ranking', '1')]
# [('player', 'http://www.wikidata.org/entity/Q1426'), ('label', 'Roger Federer'), ('ranking', '1')]
# [('player', 'http://www.wikidata.org/entity/Q30767'), ('label', 'Caroline Wozniacki'), ('ranking', '1')]
# [('player', 'http://www.wikidata.org/entity/Q5812'), ('label', 'Novak Djokovic'), ('ranking', '1')]
# [('player', 'http://www.wikidata.org/entity/Q231960'), ('label', 'Michaëlla Krajicek'), ('ranking', '1')]
# [('player', 'http://www.wikidata.org/entity/Q77178'), ('label', 'Angelique Kerber'), ('ranking', '1')]
# [('player', 'http://www.wikidata.org/entity/Q11666'), ('label', 'Maria Sharapova'), ('ranking', '1')]
# [('player', 'http://www.wikidata.org/entity/Q14286'), ('label', 'Chris Evert'), ('ranking', '1')]
# [('player', 'http://www.wikidata.org/entity/Q229087'), ('label', 'Peng Shuai'), ('ranking', '1')]
# [('player', 'http://www.wikidata.org/entity/Q230156'), ('label', 'Simona Halep'), ('ranking', '1')]
# [('player', 'http://www.wikidata.org/entity/Q9446'), ('label', 'Pete Sampras'), ('ranking', '1')]
# [('player', 'http://www.wikidata.org/entity/Q188080'), ('label', 'Arantxa Sánchez Vicario'), ('ranking', '1')]
# [('player', 'http://www.wikidata.org/entity/Q233243'), ('label', 'Natasha Zvereva'), ('ranking', '1')]
# [('player', 'http://www.wikidata.org/entity/Q233332'), ('label', 'Gigi Fernández'), ('ranking', '1')]
# [('player', 'http://www.wikidata.org/entity/Q133318'), ('label', 'Marat Safin'), ('ranking', '1')]
# [('player', 'http://www.wikidata.org/entity/Q429013'), ('label', 'Emilio Sánchez'), ('ranking', '1')]
# [('player', 'http://www.wikidata.org/entity/Q11682'), ('label', 'Justine Henin'), ('ranking', '1')]
# [('player', 'http://www.wikidata.org/entity/Q193361'), ('label', 'Carlos Moyá'), ('ranking', '1')]
# [('player', 'http://www.wikidata.org/entity/Q1355458'), ('label', 'Robert Farah'), ('ranking', '1')]
# [('player', 'http://www.wikidata.org/entity/Q229151'), ('label', 'Helena Suková'), ('ranking', '1')]
# [('player', 'http://www.wikidata.org/entity/Q53396'), ('label', 'Jim Courier'), ('ranking', '1')]
# [('player', 'http://www.wikidata.org/entity/Q10132'), ('label', 'Rafael Nadal'), ('ranking', '1')]
# [('player', 'http://www.wikidata.org/entity/Q234480'), ('label', 'Květa Peschke'), ('ranking', '1')]
# [('player', 'http://www.wikidata.org/entity/Q173633'), ('label', 'Monica Seles'), ('ranking', '1')]
# [('player', 'http://www.wikidata.org/entity/Q11677'), ('label', 'Lindsay Davenport'), ('ranking', '1')]
# [('player', 'http://www.wikidata.org/entity/Q180104'), ('label', 'Lleyton Hewitt'), ('ranking', '1')]
# [('player', 'http://www.wikidata.org/entity/Q221359'), ('label', 'Max Mirnyi'), ('ranking', '1')]
# [('player', 'http://www.wikidata.org/entity/Q229121'), ('label', 'Jana Novotná'), ('ranking', '1')]
# [('player', 'http://www.wikidata.org/entity/Q229128'), ('label', 'Cara Black'), ('ranking', '1')]
# [('player', 'http://www.wikidata.org/entity/Q242959'), ('label', 'Kristina Mladenovic'), ('ranking', '1')]
# [('player', 'http://www.wikidata.org/entity/Q560151'), ('label', 'Jacco Eltingh'), ('ranking', '1')]
# [('player', 'http://www.wikidata.org/entity/Q185722'), ('label', 'Juan Carlos Ferrero'), ('ranking', '1')]
# [('player', 'http://www.wikidata.org/entity/Q228989'), ('label', 'Lucie Šafářová'), ('ranking', '1')]
# [('player', 'http://www.wikidata.org/entity/Q11680'), ('label', 'Jennifer Capriati'), ('ranking', '1')]
# [('player', 'http://www.wikidata.org/entity/Q228559'), ('label', 'Evonne Goolagong Cawley'), ('ranking', '1')]
# [('player', 'http://www.wikidata.org/entity/Q11578'), ('label', 'Venus Williams'), ('ranking', '1')]
# [('player', 'http://www.wikidata.org/entity/Q54654'), ('label', 'Pam Shriver'), ('ranking', '1')]
# [('player', 'http://www.wikidata.org/entity/Q240695'), ('label', 'Larisa Neiland'), ('ranking', '1')]
# [('player', 'http://www.wikidata.org/entity/Q1029664'), ('label', 'Dinara Safina'), ('ranking', '1')]
# [('player', 'http://www.wikidata.org/entity/Q207528'), ('label', 'Flavia Pennetta'), ('ranking', '1')]
# [('player', 'http://www.wikidata.org/entity/Q207705'), ('label', 'Yevgeny Kafelnikov'), ('ranking', '1')]
# [('player', 'http://www.wikidata.org/entity/Q225589'), ('label', 'Corina Morariu'), ('ranking', '1')]
# [('player', 'http://www.wikidata.org/entity/Q30758'), ('label', 'Ana Ivanovic'), ('ranking', '1')]
# [('player', 'http://www.wikidata.org/entity/Q204068'), ('label', 'Patrick Rafter'), ('ranking', '1')]
# [('player', 'http://www.wikidata.org/entity/Q229474'), ('label', 'Paola Suárez'), ('ranking', '1')]
# [('player', 'http://www.wikidata.org/entity/Q29441'), ('label', 'Paul Haarhuis'), ('ranking', '1')]
# [('player', 'http://www.wikidata.org/entity/Q317974'), ('label', 'Nicolas Mahut'), ('ranking', '1')]
# [('player', 'http://www.wikidata.org/entity/Q270249'), ('label', 'Elina Svitolina'), ('ranking', '1')]
# [('player', 'http://www.wikidata.org/entity/Q312464'), ('label', 'John Newcombe'), ('ranking', '1')]
# [('player', 'http://www.wikidata.org/entity/Q54690'), ('label', 'Ellsworth Vines'), ('ranking', '1')]
# [('player', 'http://www.wikidata.org/entity/Q190723'), ('label', 'Gustavo Kuerten'), ('ranking', '1')]
# [('player', 'http://www.wikidata.org/entity/Q54545'), ('label', 'Martina Navratilova'), ('ranking', '1')]
# [('player', 'http://www.wikidata.org/entity/Q426049'), ('label', 'John Fitzgerald'), ('ranking', '1')]
# [('player', 'http://www.wikidata.org/entity/Q11052500'), ('label', 'Barbora Krejčíková'), ('ranking', '1')]
# [('player', 'http://www.wikidata.org/entity/Q84056'), ('label', 'Ashleigh Barty'), ('ranking', '1')]
# [('player', 'http://www.wikidata.org/entity/Q54537'), ('label', 'Bethanie Mattek-Sands'), ('ranking', '1')]
# [('player', 'http://www.wikidata.org/entity/Q953688'), ('label', 'Ekaterina Valeryevna Makarova'), ('ranking', '1')]
# [('player', 'http://www.wikidata.org/entity/Q3720044'), ('label', 'Kateřina Siniaková'), ('ranking', '1')]
# [('player', 'http://www.wikidata.org/entity/Q1588571'), ('label', 'Mate Pavić'), ('ranking', '1')]
# [('player', 'http://www.wikidata.org/entity/Q17466583'), ('label', 'Naomi Osaka'), ('ranking', '1')]
# [('player', 'http://www.wikidata.org/entity/Q503183'), ('label', 'Arthur Gore'), ('ranking', '1')]
# [('player', 'http://www.wikidata.org/entity/Q53326'), ('label', 'Tracy Austin'), ('ranking', '1')]
# [('player', 'http://www.wikidata.org/entity/Q229132'), ('label', 'Gisela Dulko'), ('ranking', '1')]
# [('player', 'http://www.wikidata.org/entity/Q608657'), ('label', 'Ken Flach'), ('ranking', '1')]
# [('player', 'http://www.wikidata.org/entity/Q24955766'), ('label', 'Anastasija Potapova'), ('ranking', '1')]
# [('player', 'http://www.wikidata.org/entity/Q29052147'), ('label', 'María Camila Osorio Serrano'), ('ranking', '1')]
# [('player', 'http://www.wikidata.org/entity/Q524807'), ('label', 'JoAnne Russell'), ('ranking', '1')]
# [('player', 'http://www.wikidata.org/entity/Q20898017'), ('label', 'Claire Liu'), ('ranking', '1')]
# [('player', 'http://www.wikidata.org/entity/Q41799108'), ('label', 'Wang Xiyu'), ('ranking', '1')]
# 111

# %%
# getting the countries of all the players who ranked 1
queryString = """
SELECT ?player ?ranking ?label
WHERE
{
   # ?player wdt:P106 wd:Q10833314.
   # ?player wdt:P1352 ?ranking.
   # ?player wdt:P1532 ?country.

   FILTER (datatype(?ranking) = xsd:int)
   FILTER("1"^^xsd:int = ?ranking)
   
   # ?country sc:name ?label
}
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('player', 'http://www.wikidata.org/entity/Q232566'), ('ranking', '1'), ('label', 'Chinese Taipei')]
# [('player', 'http://www.wikidata.org/entity/Q234624'), ('ranking', '1'), ('label', 'Chinese Taipei')]
# [('player', 'http://www.wikidata.org/entity/Q221908'), ('ranking', '1'), ('label', 'France')]
# [('player', 'http://www.wikidata.org/entity/Q180872'), ('ranking', '1'), ('label', 'France')]
# [('player', 'http://www.wikidata.org/entity/Q241320'), ('ranking', '1'), ('label', 'France')]
# [('player', 'http://www.wikidata.org/entity/Q242959'), ('ranking', '1'), ('label', 'France')]
# [('player', 'http://www.wikidata.org/entity/Q317974'), ('ranking', '1'), ('label', 'France')]
# [('player', 'http://www.wikidata.org/entity/Q503183'), ('ranking', '1'), ('label', 'United Kingdom')]
# [('player', 'http://www.wikidata.org/entity/Q229087'), ('ranking', '1'), ('label', "People's Republic of China")]
# [('player', 'http://www.wikidata.org/entity/Q41799108'), ('ranking', '1'), ('label', "People's Republic of China")]
# [('player', 'http://www.wikidata.org/entity/Q240695'), ('ranking', '1'), ('label', 'Soviet Union')]
# [('player', 'http://www.wikidata.org/entity/Q190723'), ('ranking', '1'), ('label', 'Brazil')]
# [('player', 'http://www.wikidata.org/entity/Q487182'), ('ranking', '1'), ('label', 'Russia')]
# [('player', 'http://www.wikidata.org/entity/Q634844'), ('ranking', '1'), ('label', 'Russia')]
# [('player', 'http://www.wikidata.org/entity/Q131120'), ('ranking', '1'), ('label', 'Russia')]
# [('player', 'http://www.wikidata.org/entity/Q11666'), ('ranking', '1'), ('label', 'Russia')]
# [('player', 'http://www.wikidata.org/entity/Q133318'), ('ranking', '1'), ('label', 'Russia')]
# [('player', 'http://www.wikidata.org/entity/Q1029664'), ('ranking', '1'), ('label', 'Russia')]
# [('player', 'http://www.wikidata.org/entity/Q207705'), ('ranking', '1'), ('label', 'Russia')]
# [('player', 'http://www.wikidata.org/entity/Q953688'), ('ranking', '1'), ('label', 'Russia')]
# [('player', 'http://www.wikidata.org/entity/Q24955766'), ('ranking', '1'), ('label', 'Russia')]
# [('player', 'http://www.wikidata.org/entity/Q298542'), ('ranking', '1'), ('label', 'Canada')]
# [('player', 'http://www.wikidata.org/entity/Q229100'), ('ranking', '1'), ('label', 'Japan')]
# [('player', 'http://www.wikidata.org/entity/Q17466583'), ('ranking', '1'), ('label', 'Japan')]
# [('player', 'http://www.wikidata.org/entity/Q11662'), ('ranking', '1'), ('label', 'Germany')]
# [('player', 'http://www.wikidata.org/entity/Q76334'), ('ranking', '1'), ('label', 'Germany')]
# [('player', 'http://www.wikidata.org/entity/Q77178'), ('ranking', '1'), ('label', 'Germany')]
# [('player', 'http://www.wikidata.org/entity/Q10118'), ('ranking', '1'), ('label', 'Belarus')]
# [('player', 'http://www.wikidata.org/entity/Q233243'), ('ranking', '1'), ('label', 'Belarus')]
# [('player', 'http://www.wikidata.org/entity/Q221359'), ('ranking', '1'), ('label', 'Belarus')]
# [('player', 'http://www.wikidata.org/entity/Q211428'), ('ranking', '1'), ('label', 'Estonia')]
# [('player', 'http://www.wikidata.org/entity/Q240695'), ('ranking', '1'), ('label', 'Latvia')]
# [('player', 'http://www.wikidata.org/entity/Q270249'), ('ranking', '1'), ('label', 'Ukraine')]
# [('player', 'http://www.wikidata.org/entity/Q289365'), ('ranking', '1'), ('label', 'Czech Republic')]
# [('player', 'http://www.wikidata.org/entity/Q229151'), ('ranking', '1'), ('label', 'Czech Republic')]
# [('player', 'http://www.wikidata.org/entity/Q234480'), ('ranking', '1'), ('label', 'Czech Republic')]
# [('player', 'http://www.wikidata.org/entity/Q229121'), ('ranking', '1'), ('label', 'Czech Republic')]
# [('player', 'http://www.wikidata.org/entity/Q228989'), ('ranking', '1'), ('label', 'Czech Republic')]
# [('player', 'http://www.wikidata.org/entity/Q54545'), ('ranking', '1'), ('label', 'Czech Republic')]
# [('player', 'http://www.wikidata.org/entity/Q11052500'), ('ranking', '1'), ('label', 'Czech Republic')]
# [('player', 'http://www.wikidata.org/entity/Q3720044'), ('ranking', '1'), ('label', 'Czech Republic')]
# [('player', 'http://www.wikidata.org/entity/Q229116'), ('ranking', '1'), ('label', 'Slovenia')]
# [('player', 'http://www.wikidata.org/entity/Q230156'), ('ranking', '1'), ('label', 'Romania')]
# [('player', 'http://www.wikidata.org/entity/Q1588571'), ('ranking', '1'), ('label', 'Croatia')]
# [('player', 'http://www.wikidata.org/entity/Q229093'), ('ranking', '1'), ('label', 'Spain')]
# [('player', 'http://www.wikidata.org/entity/Q34276'), ('ranking', '1'), ('label', 'Spain')]
# [('player', 'http://www.wikidata.org/entity/Q188080'), ('ranking', '1'), ('label', 'Spain')]
# [('player', 'http://www.wikidata.org/entity/Q429013'), ('ranking', '1'), ('label', 'Spain')]
# [('player', 'http://www.wikidata.org/entity/Q193361'), ('ranking', '1'), ('label', 'Spain')]
# [('player', 'http://www.wikidata.org/entity/Q10132'), ('ranking', '1'), ('label', 'Spain')]
# [('player', 'http://www.wikidata.org/entity/Q185722'), ('ranking', '1'), ('label', 'Spain')]
# [('player', 'http://www.wikidata.org/entity/Q231960'), ('ranking', '1'), ('label', 'Kingdom of the Netherlands')]
# [('player', 'http://www.wikidata.org/entity/Q53393'), ('ranking', '1'), ('label', 'United States of America')]
# [('player', 'http://www.wikidata.org/entity/Q1743002'), ('ranking', '1'), ('label', 'United States of America')]
# [('player', 'http://www.wikidata.org/entity/Q30217670'), ('ranking', '1'), ('label', 'United States of America')]
# [('player', 'http://www.wikidata.org/entity/Q182736'), ('ranking', '1'), ('label', 'United States of America')]
# [('player', 'http://www.wikidata.org/entity/Q270414'), ('ranking', '1'), ('label', 'United States of America')]
# [('player', 'http://www.wikidata.org/entity/Q10129'), ('ranking', '1'), ('label', 'United States of America')]
# [('player', 'http://www.wikidata.org/entity/Q11459'), ('ranking', '1'), ('label', 'United States of America')]
# [('player', 'http://www.wikidata.org/entity/Q14286'), ('ranking', '1'), ('label', 'United States of America')]
# [('player', 'http://www.wikidata.org/entity/Q233332'), ('ranking', '1'), ('label', 'United States of America')]
# [('player', 'http://www.wikidata.org/entity/Q173633'), ('ranking', '1'), ('label', 'United States of America')]
# [('player', 'http://www.wikidata.org/entity/Q11677'), ('ranking', '1'), ('label', 'United States of America')]
# [('player', 'http://www.wikidata.org/entity/Q11680'), ('ranking', '1'), ('label', 'United States of America')]
# [('player', 'http://www.wikidata.org/entity/Q11578'), ('ranking', '1'), ('label', 'United States of America')]
# [('player', 'http://www.wikidata.org/entity/Q54654'), ('ranking', '1'), ('label', 'United States of America')]
# [('player', 'http://www.wikidata.org/entity/Q225589'), ('ranking', '1'), ('label', 'United States of America')]
# [('player', 'http://www.wikidata.org/entity/Q54545'), ('ranking', '1'), ('label', 'United States of America')]
# [('player', 'http://www.wikidata.org/entity/Q54537'), ('ranking', '1'), ('label', 'United States of America')]
# [('player', 'http://www.wikidata.org/entity/Q53326'), ('ranking', '1'), ('label', 'United States of America')]
# [('player', 'http://www.wikidata.org/entity/Q608657'), ('ranking', '1'), ('label', 'United States of America')]
# [('player', 'http://www.wikidata.org/entity/Q524807'), ('ranking', '1'), ('label', 'United States of America')]
# [('player', 'http://www.wikidata.org/entity/Q20898017'), ('ranking', '1'), ('label', 'United States of America')]
# [('player', 'http://www.wikidata.org/entity/Q11685'), ('ranking', '1'), ('label', 'Belgium')]
# [('player', 'http://www.wikidata.org/entity/Q11682'), ('ranking', '1'), ('label', 'Belgium')]
# [('player', 'http://www.wikidata.org/entity/Q13538'), ('ranking', '1'), ('label', 'Finland')]
# [('player', 'http://www.wikidata.org/entity/Q455136'), ('ranking', '1'), ('label', 'Sweden')]
# [('player', 'http://www.wikidata.org/entity/Q189542'), ('ranking', '1'), ('label', 'Sweden')]
# [('player', 'http://www.wikidata.org/entity/Q104506'), ('ranking', '1'), ('label', 'Sweden')]
# [('player', 'http://www.wikidata.org/entity/Q30767'), ('ranking', '1'), ('label', 'Denmark')]
# [('player', 'http://www.wikidata.org/entity/Q207352'), ('ranking', '1'), ('label', 'Poland')]
# [('player', 'http://www.wikidata.org/entity/Q345626'), ('ranking', '1'), ('label', 'Poland')]
# [('player', 'http://www.wikidata.org/entity/Q95162'), ('ranking', '1'), ('label', 'Italy')]
# [('player', 'http://www.wikidata.org/entity/Q207528'), ('ranking', '1'), ('label', 'Italy')]
# [('player', 'http://www.wikidata.org/entity/Q134720'), ('ranking', '1'), ('label', 'Switzerland')]
# [('player', 'http://www.wikidata.org/entity/Q1426'), ('ranking', '1'), ('label', 'Switzerland')]
# [('player', 'http://www.wikidata.org/entity/Q5812'), ('ranking', '1'), ('label', 'Serbia')]
# [('player', 'http://www.wikidata.org/entity/Q30758'), ('ranking', '1'), ('label', 'Serbia')]
# [('player', 'http://www.wikidata.org/entity/Q191766'), ('ranking', '1'), ('label', 'Australia')]
# [('player', 'http://www.wikidata.org/entity/Q228559'), ('ranking', '1'), ('label', 'Australia')]
# [('player', 'http://www.wikidata.org/entity/Q426049'), ('ranking', '1'), ('label', 'Australia')]
# [('player', 'http://www.wikidata.org/entity/Q84056'), ('ranking', '1'), ('label', 'Australia')]
# [('player', 'http://www.wikidata.org/entity/Q132147'), ('ranking', '1'), ('label', 'India')]
# [('player', 'http://www.wikidata.org/entity/Q921488'), ('ranking', '1'), ('label', 'Colombia')]
# [('player', 'http://www.wikidata.org/entity/Q1355458'), ('ranking', '1'), ('label', 'Colombia')]
# [('player', 'http://www.wikidata.org/entity/Q173633'), ('ranking', '1'), ('label', 'Socialist Federal Republic of Yugoslavia')]
# [('player', 'http://www.wikidata.org/entity/Q182736'), ('ranking', '1'), ('label', 'Czechoslovakia')]
# [('player', 'http://www.wikidata.org/entity/Q229121'), ('ranking', '1'), ('label', 'Czechoslovakia')]
# [('player', 'http://www.wikidata.org/entity/Q54545'), ('ranking', '1'), ('label', 'Czechoslovakia')]
# 99

# %% [markdown]
# Final query for this task

# %%
# write your final query
queryString = """
SELECT DISTINCT ?country_iri ?label
WHERE
{
    SELECT ?player ?ranking ?country_iri ?label
    WHERE
    {
       # ?player wdt:P106 wd:Q10833314.
       # ?player wdt:P1352 ?ranking.
       # ?player wdt:P1532 ?country_iri.

       FILTER (datatype(?ranking) = xsd:int)
       FILTER("1"^^xsd:int = ?ranking)

       # ?country_iri sc:name ?label
    }
}
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('country_iri', 'http://www.wikidata.org/entity/Q216923'), ('label', 'Chinese Taipei')]
# [('country_iri', 'http://www.wikidata.org/entity/Q142'), ('label', 'France')]
# [('country_iri', 'http://www.wikidata.org/entity/Q145'), ('label', 'United Kingdom')]
# [('country_iri', 'http://www.wikidata.org/entity/Q148'), ('label', "People's Republic of China")]
# [('country_iri', 'http://www.wikidata.org/entity/Q15180'), ('label', 'Soviet Union')]
# [('country_iri', 'http://www.wikidata.org/entity/Q155'), ('label', 'Brazil')]
# [('country_iri', 'http://www.wikidata.org/entity/Q159'), ('label', 'Russia')]
# [('country_iri', 'http://www.wikidata.org/entity/Q16'), ('label', 'Canada')]
# [('country_iri', 'http://www.wikidata.org/entity/Q17'), ('label', 'Japan')]
# [('country_iri', 'http://www.wikidata.org/entity/Q183'), ('label', 'Germany')]
# [('country_iri', 'http://www.wikidata.org/entity/Q184'), ('label', 'Belarus')]
# [('country_iri', 'http://www.wikidata.org/entity/Q191'), ('label', 'Estonia')]
# [('country_iri', 'http://www.wikidata.org/entity/Q211'), ('label', 'Latvia')]
# [('country_iri', 'http://www.wikidata.org/entity/Q212'), ('label', 'Ukraine')]
# [('country_iri', 'http://www.wikidata.org/entity/Q213'), ('label', 'Czech Republic')]
# [('country_iri', 'http://www.wikidata.org/entity/Q215'), ('label', 'Slovenia')]
# [('country_iri', 'http://www.wikidata.org/entity/Q218'), ('label', 'Romania')]
# [('country_iri', 'http://www.wikidata.org/entity/Q224'), ('label', 'Croatia')]
# [('country_iri', 'http://www.wikidata.org/entity/Q29'), ('label', 'Spain')]
# [('country_iri', 'http://www.wikidata.org/entity/Q29999'), ('label', 'Kingdom of the Netherlands')]
# [('country_iri', 'http://www.wikidata.org/entity/Q30'), ('label', 'United States of America')]
# [('country_iri', 'http://www.wikidata.org/entity/Q31'), ('label', 'Belgium')]
# [('country_iri', 'http://www.wikidata.org/entity/Q33'), ('label', 'Finland')]
# [('country_iri', 'http://www.wikidata.org/entity/Q34'), ('label', 'Sweden')]
# [('country_iri', 'http://www.wikidata.org/entity/Q35'), ('label', 'Denmark')]
# [('country_iri', 'http://www.wikidata.org/entity/Q36'), ('label', 'Poland')]
# [('country_iri', 'http://www.wikidata.org/entity/Q38'), ('label', 'Italy')]
# [('country_iri', 'http://www.wikidata.org/entity/Q39'), ('label', 'Switzerland')]
# [('country_iri', 'http://www.wikidata.org/entity/Q403'), ('label', 'Serbia')]
# [('country_iri', 'http://www.wikidata.org/entity/Q408'), ('label', 'Australia')]
# [('country_iri', 'http://www.wikidata.org/entity/Q668'), ('label', 'India')]
# [('country_iri', 'http://www.wikidata.org/entity/Q739'), ('label', 'Colombia')]
# [('country_iri', 'http://www.wikidata.org/entity/Q83286'), ('label', 'Socialist Federal Republic of Yugoslavia')]
# [('country_iri', 'http://www.wikidata.org/entity/Q33946'), ('label', 'Czechoslovakia')]
# 34

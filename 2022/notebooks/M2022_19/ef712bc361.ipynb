# %% [markdown]
# # General instructions
#
# The goal of the project is to materialize a set of **exploratory workloads** over a real-world, large-scale,  open-domain KG: [WikiData](https://www.wikidata.org/wiki/Wikidata:Main_Page)
#
# An exploratory workload  is composed by a set of queries, where each query is related to the information obtained previously.
#
# An exploratory workload starts with a usually vague, open ended question, and does not assume the person issuing the workload has a clear understanding of the data contained in the target database or its structure.
#
# Remeber that:
#
# 1. All the queries must run in the python notebook
# 2. You can use classes and properties only if you find them via a SPARQL query that must be present in the notebook
# 3. You do not delete useless queries. Keep everything that is synthatically valid
#
# ```
# ?p <http://schema.org/name> ?name .
# ```
#
#     is the BGP returning a human-readable name of a property or a class in Wikidata.

# %%
## SETUP used later

from SPARQLWrapper import SPARQLWrapper, JSON


prefixString = """
##-ef712bc361-##
PREFIX wd: <http://www.wikidata.org/entity/> 
PREFIX wdt: <http://www.wikidata.org/prop/direct/> 
PREFIX sc: <http://schema.org/>
"""

# select and construct queries
def run_query(queryString,verbose = True):
    to_run = prefixString + "\n" + queryString

    sparql = SPARQLWrapper("http://a256-gc1-03.srv.aau.dk:5820/sparql")
    sparql.setTimeout(300)
    sparql.setReturnFormat(JSON)
    sparql.setQuery(to_run)

    try :
        results = sparql.query()
        json_results = results.convert()
        if len(json_results['results']['bindings'])==0:
            print("Empty")
            return []
        array = []
        for bindings in json_results['results']['bindings']:
            app =  [ (var, value['value'])  for var, value in bindings.items() ] 
            if verbose:
                print( app)
            array.append(app)
        if verbose:
            print(len(array))
        return array

    except Exception as e :
        print("The operation failed", e)
    
# ASk queries
def run_ask_query(queryString):
    to_run = prefixString + "\n" + queryString

    sparql = SPARQLWrapper("http://a256-gc1-03.srv.aau.dk:5820/sparql")
    sparql.setTimeout(300)
    sparql.setReturnFormat(JSON)
    sparql.setQuery(to_run)

    try :
        return sparql.query().convert()

    except Exception as e :
        print("The operation failed", e)

# %% [markdown]
# # Sport Workflow Series (Basketball and NBA seasons explorative search")
#
# Consider the following exploratory information need:
#
# >  investigate the world of basketball. Compare french teams and US teams, country of citizenship of NBA players, and teams which won NBA seasons.

# %% [markdown]
# ## Useful URIs for the current workflow
# The following are given:
#
# | IRI           | Description   | Role      |
# | -----------   | -----------   |-----------|
# | `wdt:P1647`   | subproperty   | predicate |
# | `wdt:P31`     | instance of   | predicate |
# | `wdt:P106`    | profession    | predicate |
# | `wdt:P279`    | subclass      | predicate |
# | `wdt:P27`     | nationality   | predicate |
# | `wd:Q5`| Human       | node |
# | `wd:Q41421`| Michael Jordan     | node |
# | `wd:Q25369`| Kobe Bryant     | node |

# %% [markdown]
# Also consider
#
# ```
# wd:Q41421 ?p ?obj .
# ```
#
# is the BGP to retrieve all **properties of Michael Jordan**
#
# Please consider that when you return a resource, you should return the IRI and the label of the resource. In particular, when the task require you to identify a BGP the result set must always be a list of couples IRI - label.
#
#
#
# The workload should:
#
#
# 1. Identify the BGP for basketball player.
#
# 2. Identify the BGP for basketball.
#
# 3. Identify the BGP for basketball team.
#
# 4. Return all french basketball teams born before 1930 (the result set must be a list of triples basketball team IRI, label and year of inception).
#
# 5. Return all the NBA season (the result set must be a list of couples NBA season IRI, label)
#
# 6. Consider only the basketball teams which Michael Jordan and Kobe Bryant played. Return the number of NBA seasons won by these teams (the result set must be a list of triples basketball team IRI, label and #victories. Return a number for each basketball team even if they never won a season).
#
# 7. Consider only NBA (National Basketball Association) basketball teams and all basketball players who played in one of these teams at least once. Also consider the country of citizenship of the players with the related continent. Return for each continent the number of players who played in an NBA basketball teams. (the result set must be triples of continent IRI, label and #players)
#
# 8. Identify the BGP for the NBA Defensive Player of the Year Award (see https://en.wikipedia.org/wiki/NBA_Defensive_Player_of_the_Year_Award)
#
# 9. Consider the players who won the NBA Defensive Player of the Year Award. Return for these players the number of NBA Defensive Player of the Year Award won in their career (the result set must be triples of player IRI, label and #victories)

# %% [markdown]
# ## Task 1
# Identify the BGP for basketball player.

# %%
# query example
queryString = """
SELECT DISTINCT ?p ?name
WHERE {
   # bind something
   wd:Q41421 ?p ?obj .
   # get the label
   # ?p sc:name ?name.
}
LIMIT 150
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P1006'), ('name', 'Nationale Thesaurus voor Auteurs ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1015'), ('name', 'NORAF ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1048'), ('name', 'NCL ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('p', 'http://www.wikidata.org/prop/direct/P118'), ('name', 'league')]
# [('p', 'http://www.wikidata.org/prop/direct/P1207'), ('name', 'NUKAT ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1258'), ('name', 'Rotten Tomatoes ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1263'), ('name', 'NNDB people ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1266'), ('name', 'AlloCiné person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1280'), ('name', 'CONOR.SI ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1285'), ('name', 'Munzinger Sport number')]
# [('p', 'http://www.wikidata.org/prop/direct/P1296'), ('name', 'Gran Enciclopèdia Catalana ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1315'), ('name', 'NLA Trove ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1343'), ('name', 'described by source')]
# [('p', 'http://www.wikidata.org/prop/direct/P1344'), ('name', 'participant in')]
# [('p', 'http://www.wikidata.org/prop/direct/P1368'), ('name', 'LNB ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1375'), ('name', 'NSK ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1411'), ('name', 'nominated for')]
# [('p', 'http://www.wikidata.org/prop/direct/P1412'), ('name', 'languages spoken, written or signed')]
# [('p', 'http://www.wikidata.org/prop/direct/P1417'), ('name', 'Encyclopædia Britannica Online ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1447'), ('name', 'Sports-Reference.com Olympic athlete ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1449'), ('name', 'nickname')]
# [('p', 'http://www.wikidata.org/prop/direct/P1477'), ('name', 'birth name')]
# [('p', 'http://www.wikidata.org/prop/direct/P1532'), ('name', 'country for sport')]
# [('p', 'http://www.wikidata.org/prop/direct/P1559'), ('name', 'name in native language')]
# [('p', 'http://www.wikidata.org/prop/direct/P1618'), ('name', 'sport number')]
# [('p', 'http://www.wikidata.org/prop/direct/P166'), ('name', 'award received')]
# [('p', 'http://www.wikidata.org/prop/direct/P1670'), ('name', 'Canadiana Authorities ID (former scheme)')]
# [('p', 'http://www.wikidata.org/prop/direct/P1695'), ('name', 'NLP ID (unique)')]
# [('p', 'http://www.wikidata.org/prop/direct/P1712'), ('name', 'Metacritic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P172'), ('name', 'ethnic group')]
# [('p', 'http://www.wikidata.org/prop/direct/P1741'), ('name', 'GTAA ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P18'), ('name', 'image')]
# [('p', 'http://www.wikidata.org/prop/direct/P1830'), ('name', 'owner of')]
# [('p', 'http://www.wikidata.org/prop/direct/P1889'), ('name', 'different from')]
# [('p', 'http://www.wikidata.org/prop/direct/P1890'), ('name', 'CCAB ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P19'), ('name', 'place of birth')]
# [('p', 'http://www.wikidata.org/prop/direct/P1953'), ('name', 'Discogs artist ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2013'), ('name', 'Facebook ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2019'), ('name', 'AllMovie person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2031'), ('name', 'work period (start)')]
# [('p', 'http://www.wikidata.org/prop/direct/P2032'), ('name', 'work period (end)')]
# [('p', 'http://www.wikidata.org/prop/direct/P2048'), ('name', 'height')]
# [('p', 'http://www.wikidata.org/prop/direct/P2067'), ('name', 'mass')]
# [('p', 'http://www.wikidata.org/prop/direct/P21'), ('name', 'sex or gender')]
# [('p', 'http://www.wikidata.org/prop/direct/P213'), ('name', 'ISNI')]
# [('p', 'http://www.wikidata.org/prop/direct/P214'), ('name', 'VIAF ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2163'), ('name', 'FAST ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P22'), ('name', 'father')]
# [('p', 'http://www.wikidata.org/prop/direct/P227'), ('name', 'GND ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2283'), ('name', 'uses')]
# [('p', 'http://www.wikidata.org/prop/direct/P2435'), ('name', 'PORT person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P244'), ('name', 'Library of Congress authority ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P25'), ('name', 'mother')]
# [('p', 'http://www.wikidata.org/prop/direct/P2561'), ('name', 'name')]
# [('p', 'http://www.wikidata.org/prop/direct/P26'), ('name', 'spouse')]
# [('p', 'http://www.wikidata.org/prop/direct/P2600'), ('name', 'Geni.com profile ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2604'), ('name', 'Kinopoisk person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2605'), ('name', 'ČSFD person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2626'), ('name', 'Danish National Filmography person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2638'), ('name', 'TV.com ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P268'), ('name', 'Bibliothèque nationale de France ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P269'), ('name', 'IdRef ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P27'), ('name', 'country of citizenship')]
# [('p', 'http://www.wikidata.org/prop/direct/P271'), ('name', 'CiNii author ID (books)')]
# [('p', 'http://www.wikidata.org/prop/direct/P286'), ('name', 'head coach')]
# [('p', 'http://www.wikidata.org/prop/direct/P2924'), ('name', 'Great Russian Encyclopedia Online ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3056'), ('name', 'TCM Movie Database person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3065'), ('name', 'RERO ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('name', 'instance of')]
# [('p', 'http://www.wikidata.org/prop/direct/P3219'), ('name', 'Encyclopædia Universalis ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3221'), ('name', 'New York Times topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3222'), ('name', 'NE.se ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3348'), ('name', 'National Library of Greece ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3373'), ('name', 'sibling')]
# [('p', 'http://www.wikidata.org/prop/direct/P3417'), ('name', 'Quora topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3430'), ('name', 'SNAC ARK ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P345'), ('name', 'IMDb ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3478'), ('name', 'Songkick artist ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P349'), ('name', 'National Diet Library ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3527'), ('name', 'Eurobasket.com player ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3542'), ('name', 'FIBA player ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P361'), ('name', 'part of')]
# [('p', 'http://www.wikidata.org/prop/direct/P3630'), ('name', 'Babelio author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3696'), ('name', 'Sports-Reference.com college basketball player ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P373'), ('name', 'Commons category')]
# [('p', 'http://www.wikidata.org/prop/direct/P3845'), ('name', 'TV Guide person ID (former scheme)')]
# [('p', 'http://www.wikidata.org/prop/direct/P3957'), ('name', 'RealGM basketball player ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P40'), ('name', 'child')]
# [('p', 'http://www.wikidata.org/prop/direct/P413'), ('name', 'position played on team / speciality')]
# [('p', 'http://www.wikidata.org/prop/direct/P4332'), ('name', 'Deutsche Synchronkartei actor ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P434'), ('name', 'MusicBrainz artist ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P4342'), ('name', 'Store norske leksikon ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P4438'), ('name', 'BFI Films, TV and people ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P4515'), ('name', 'Prisma ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P4619'), ('name', 'National Library of Brazil ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P4666'), ('name', 'CineMagia person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P4790'), ('name', 'Basketball-Reference.com international player ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P4985'), ('name', 'TMDb person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5008'), ('name', 'on focus list of Wikimedia project')]
# [('p', 'http://www.wikidata.org/prop/direct/P5019'), ('name', 'Brockhaus Enzyklopädie online ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5033'), ('name', 'Filmweb.pl person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5361'), ('name', 'BNB person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P54'), ('name', 'member of sports team')]
# [('p', 'http://www.wikidata.org/prop/direct/P5421'), ('name', 'Trading Card Database person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P551'), ('name', 'residence')]
# [('p', 'http://www.wikidata.org/prop/direct/P552'), ('name', 'handedness')]
# [('p', 'http://www.wikidata.org/prop/direct/P5534'), ('name', 'Open Media Database person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5617'), ('name', 'Evene ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P569'), ('name', 'date of birth')]
# [('p', 'http://www.wikidata.org/prop/direct/P5905'), ('name', 'Comic Vine ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6298'), ('name', 'bgm.tv person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P641'), ('name', 'sport')]
# [('p', 'http://www.wikidata.org/prop/direct/P646'), ('name', 'Freebase ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P648'), ('name', 'Open Library ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6723'), ('name', 'BlackPast.org ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P69'), ('name', 'educated at')]
# [('p', 'http://www.wikidata.org/prop/direct/P691'), ('name', 'NKCR AUT ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7293'), ('name', 'PLWABN ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P734'), ('name', 'family name')]
# [('p', 'http://www.wikidata.org/prop/direct/P735'), ('name', 'given name')]
# [('p', 'http://www.wikidata.org/prop/direct/P7369'), ('name', 'National Library of Chile ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P737'), ('name', 'influenced by')]
# [('p', 'http://www.wikidata.org/prop/direct/P7818'), ('name', 'French Vikidia ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7859'), ('name', 'WorldCat Identities ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8179'), ('name', 'Canadiana NCF ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8189'), ('name', 'National Library of Israel J9U ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8286'), ('name', 'Olympedia people ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8548'), ('name', 'Proballers ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8796'), ('name', 'FilmPolski press collection ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8852'), ('name', 'facial hair')]
# [('p', 'http://www.wikidata.org/prop/direct/P910'), ('name', "topic's main category")]
# [('p', 'http://www.wikidata.org/prop/direct/P9404'), ('name', 'OFDb person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P947'), ('name', 'RSL ID (person)')]
# [('p', 'http://www.wikidata.org/prop/direct/P949'), ('name', 'National Library of Israel ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P950'), ('name', 'Biblioteca Nacional de España ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P9743'), ('name', 'Podchaser creator ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P989'), ('name', 'spoken text audio')]
# [('p', 'http://www.wikidata.org/prop/direct/P1826'), ('name', 'Baseball-Reference.com minor & foreign league player ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2685'), ('name', 'Basketball Reference NBA player ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3646'), ('name', 'Naismith Memorial Basketball Hall of Fame ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3647'), ('name', 'NBA.com player ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3828'), ('name', 'wears')]
# [('p', 'http://www.wikidata.org/prop/direct/P647'), ('name', 'drafted by')]
# [('p', 'http://www.wikidata.org/prop/direct/P6865'), ('name', 'eurobasket.com coach ID')]
# 145

# %% [markdown]
# Final query for this task

# %%
queryString = """
SELECT DISTINCT ?job ?jobName
WHERE {
   # using Profession property
   wd:Q41421 wdt:P106 ?job .
   
   # get the label
   # ?job sc:name ?jobName.
}
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('job', 'http://www.wikidata.org/entity/Q131524'), ('jobName', 'entrepreneur')]
# [('job', 'http://www.wikidata.org/entity/Q18814623'), ('jobName', 'autobiographer')]
# [('job', 'http://www.wikidata.org/entity/Q33999'), ('jobName', 'actor')]
# [('job', 'http://www.wikidata.org/entity/Q3665646'), ('jobName', 'basketball player')]
# [('job', 'http://www.wikidata.org/entity/Q10871364'), ('jobName', 'baseball player')]
# [('job', 'http://www.wikidata.org/entity/Q17221'), ('jobName', 'spokesperson')]
# 6

# %% [markdown]
# ## Task 2
# Identify the BGP for basketball.

# %%
# From Task 1: [('p', 'http://www.wikidata.org/prop/direct/P641'), ('name', 'sport')]

queryString = """
SELECT DISTINCT ?sport ?sportName
WHERE {
   # using Profession property
   wd:Q41421 wdt:P641 ?sport .
   
   # get the label
   # ?sport sc:name ?sportName.
}
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('sport', 'http://www.wikidata.org/entity/Q5369'), ('sportName', 'baseball')]
# [('sport', 'http://www.wikidata.org/entity/Q5372'), ('sportName', 'basketball')]
# 2

# %% [markdown]
# Final query for this task

# %%
queryString = """
SELECT DISTINCT ?sport ?sportName
WHERE {
   # using Profession property
   wd:Q41421 wdt:P641 ?sport .
   
   # get the label
   # ?sport sc:name ?sportName.
}
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('sport', 'http://www.wikidata.org/entity/Q5369'), ('sportName', 'baseball')]
# [('sport', 'http://www.wikidata.org/entity/Q5372'), ('sportName', 'basketball')]
# 2

# %% [markdown]
# ## Task 3
# Identify the BGP for basketball team.

# %%
queryString = """
SELECT DISTINCT ?job ?jobName
WHERE {
   # using Profession property
   wd:Q41421 wdt:P106 ?job .
   
   
   # get the label
   # ?job sc:name ?jobName.
}
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('job', 'http://www.wikidata.org/entity/Q131524'), ('jobName', 'entrepreneur')]
# [('job', 'http://www.wikidata.org/entity/Q18814623'), ('jobName', 'autobiographer')]
# [('job', 'http://www.wikidata.org/entity/Q33999'), ('jobName', 'actor')]
# [('job', 'http://www.wikidata.org/entity/Q3665646'), ('jobName', 'basketball player')]
# [('job', 'http://www.wikidata.org/entity/Q10871364'), ('jobName', 'baseball player')]
# [('job', 'http://www.wikidata.org/entity/Q17221'), ('jobName', 'spokesperson')]
# 6

# %%
#[('job', 'http://www.wikidata.org/entity/Q3665646'), ('jobName', 'basketball player')]

queryString = """
SELECT DISTINCT ?p ?pname ?o ?oname
WHERE {
   # Finding basketball player properties
   wd:Q3665646 ?p ?o .
   
   
   # get the label
   # ?p sc:name ?pname.
   # ?o sc:name ?oname .
}
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pname', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q18536342'), ('oname', 'competitive player')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pname', 'properties for this type'), ('o', 'http://www.wikidata.org/entity/P4557'), ('oname', 'Indiana Basketball Hall of Fame ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pname', 'instance of'), ('o', 'http://www.wikidata.org/entity/Q28640'), ('oname', 'profession')]
# [('p', 'http://www.wikidata.org/prop/direct/P425'), ('pname', 'field of this occupation'), ('o', 'http://www.wikidata.org/entity/Q5372'), ('oname', 'basketball')]
# [('p', 'http://www.wikidata.org/prop/direct/P641'), ('pname', 'sport'), ('o', 'http://www.wikidata.org/entity/Q5372'), ('oname', 'basketball')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pname', 'properties for this type'), ('o', 'http://www.wikidata.org/entity/P2685'), ('oname', 'Basketball Reference NBA player ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pname', 'properties for this type'), ('o', 'http://www.wikidata.org/entity/P3647'), ('oname', 'NBA.com player ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pname', 'properties for this type'), ('o', 'http://www.wikidata.org/entity/P3696'), ('oname', 'Sports-Reference.com college basketball player ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pname', 'properties for this type'), ('o', 'http://www.wikidata.org/entity/P4561'), ('oname', 'Basketball Reference WNBA player ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pname', 'properties for this type'), ('o', 'http://www.wikidata.org/entity/P4744'), ('oname', 'Basketball-Reference.com NBA G League player ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P361'), ('pname', 'part of'), ('o', 'http://www.wikidata.org/entity/Q13393265'), ('oname', 'basketball team')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pname', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q2066131'), ('oname', 'athlete')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pname', 'properties for this type'), ('o', 'http://www.wikidata.org/entity/P3957'), ('oname', 'RealGM basketball player ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P425'), ('pname', 'field of this occupation'), ('o', 'http://www.wikidata.org/entity/Q48890'), ('oname', 'college basketball')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pname', 'properties for this type'), ('o', 'http://www.wikidata.org/entity/P3685'), ('oname', 'ESPN.com NBA player ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pname', 'properties for this type'), ('o', 'http://www.wikidata.org/entity/P6063'), ('oname', 'Scoresway basketball person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pname', 'properties for this type'), ('o', 'http://www.wikidata.org/entity/P5722'), ('oname', 'Greek Basket League ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pname', 'properties for this type'), ('o', 'http://www.wikidata.org/entity/P5725'), ('oname', 'Baloncesto Superior Nacional ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pname', 'properties for this type'), ('o', 'http://www.wikidata.org/entity/P4796'), ('oname', 'Basketball-Reference.com NBL player ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pname', 'properties for this type'), ('o', 'http://www.wikidata.org/entity/P4612'), ('oname', 'LKL player ID')]
# 20

# %% [markdown]
# Final query for this task

# %%
# From results: [('p', 'http://www.wikidata.org/prop/direct/P361'), ('pname', 'part of'),
#('o', 'http://www.wikidata.org/entity/Q13393265'),('oname', 'basketball team')]


queryString = """
SELECT DISTINCT ?o ?oname
WHERE {
   # Using part of property
   wd:Q3665646 wdt:P361 ?o .
   
   
   # get the label
   #?p sc:name ?pname.
   # ?o sc:name ?oname .
}
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('o', 'http://www.wikidata.org/entity/Q13393265'), ('oname', 'basketball team')]
# 1

# %% [markdown]
# ## Task 4
# Return all french basketball teams born before 1930 (the result set must be a list of triples basketball team IRI, label and year of inception).

# %%
#From Task 1: [('p', 'http://www.wikidata.org/prop/direct/P54'), ('name', 'member of sports team')]

queryString = """
SELECT DISTINCT ?team ?teamName
WHERE {
   # Finding basketball team properties
   wd:Q41421 wdt:P54 ?team.
   
   
   # get the label
   # ?team sc:name ?teamName .
}
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('team', 'http://www.wikidata.org/entity/Q128109'), ('teamName', 'Chicago Bulls')]
# [('team', 'http://www.wikidata.org/entity/Q169165'), ('teamName', 'Washington Wizards')]
# [('team', 'http://www.wikidata.org/entity/Q2747877'), ('teamName', 'Birmingham Barons')]
# [('team', 'http://www.wikidata.org/entity/Q3476102'), ('teamName', 'Scottsdale Scorpions')]
# [('team', 'http://www.wikidata.org/entity/Q4412061'), ('teamName', "North Carolina Tar Heels men's basketball")]
# 5

# %%
#From results: [('team', 'http://www.wikidata.org/entity/Q128109'), ('teamName', 'Chicago Bulls')]


queryString = """
SELECT DISTINCT ?p ?pname ?o ?oname
WHERE {
   # Finding sports club properties
   wd:Q128109 ?p ?o.
   
   
   # get the label
   # ?p sc:name ?pname.
   # ?o sc:name ?oname .
}
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P859'), ('pname', 'sponsor'), ('o', 'http://www.wikidata.org/entity/Q174769'), ('oname', 'United Airlines')]
# [('p', 'http://www.wikidata.org/prop/direct/P115'), ('pname', 'home venue'), ('o', 'http://www.wikidata.org/entity/Q639975'), ('oname', 'United Center')]
# [('p', 'http://www.wikidata.org/prop/direct/P159'), ('pname', 'headquarters location'), ('o', 'http://www.wikidata.org/entity/Q1297'), ('oname', 'Chicago')]
# [('p', 'http://www.wikidata.org/prop/direct/P17'), ('pname', 'country'), ('o', 'http://www.wikidata.org/entity/Q30'), ('oname', 'United States of America')]
# [('p', 'http://www.wikidata.org/prop/direct/P641'), ('pname', 'sport'), ('o', 'http://www.wikidata.org/entity/Q5372'), ('oname', 'basketball')]
# [('p', 'http://www.wikidata.org/prop/direct/P118'), ('pname', 'league'), ('o', 'http://www.wikidata.org/entity/Q155223'), ('oname', 'National Basketball Association')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pname', 'instance of'), ('o', 'http://www.wikidata.org/entity/Q13393265'), ('oname', 'basketball team')]
# [('p', 'http://www.wikidata.org/prop/direct/P127'), ('pname', 'owned by'), ('o', 'http://www.wikidata.org/entity/Q5273097'), ('oname', 'Dick Klein')]
# [('p', 'http://www.wikidata.org/prop/direct/P361'), ('pname', 'part of'), ('o', 'http://www.wikidata.org/entity/Q745984'), ('oname', 'Central Division')]
# [('p', 'http://www.wikidata.org/prop/direct/P910'), ('pname', "topic's main category"), ('o', 'http://www.wikidata.org/entity/Q8879406'), ('oname', 'Category:Chicago Bulls')]
# [('p', 'http://www.wikidata.org/prop/direct/P127'), ('pname', 'owned by'), ('o', 'http://www.wikidata.org/entity/Q2662152'), ('oname', 'Jerry Reinsdorf')]
# [('p', 'http://www.wikidata.org/prop/direct/P286'), ('pname', 'head coach'), ('o', 'http://www.wikidata.org/entity/Q580808'), ('oname', 'Fred Hoiberg')]
# [('p', 'http://www.wikidata.org/prop/direct/P859'), ('pname', 'sponsor'), ('o', 'http://www.wikidata.org/entity/Q37189902'), ('oname', 'Mr. Submarine')]
# [('p', 'http://www.wikidata.org/prop/direct/P822'), ('pname', 'mascot'), ('o', 'http://www.wikidata.org/entity/Q4890070'), ('oname', 'Benny the Bull')]
# 14

# %%
# [('o', 'http://www.wikidata.org/entity/Q13393265'), ('oname', 'basketball team')]

queryString = """
SELECT DISTINCT ?p ?pname ?o ?oname
WHERE {
   # Finding basketball team properties
   wd:Q13393265 ?p ?o.
   
   
   # get the label
   # ?p sc:name ?pname.
   # ?o sc:name ?oname .
}
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pname', 'has part'), ('o', 'http://www.wikidata.org/entity/Q51747567'), ('oname', 'squad')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pname', 'has part'), ('o', 'http://www.wikidata.org/entity/Q3665646'), ('oname', 'basketball player')]
# [('p', 'http://www.wikidata.org/prop/direct/P641'), ('pname', 'sport'), ('o', 'http://www.wikidata.org/entity/Q5372'), ('oname', 'basketball')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pname', 'has part'), ('o', 'http://www.wikidata.org/entity/Q5137571'), ('oname', 'basketball coach')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pname', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q847017'), ('oname', 'sports club')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pname', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q12973014'), ('oname', 'sports team')]
# [('p', 'http://www.wikidata.org/prop/direct/P1424'), ('pname', "topic's main template"), ('o', 'http://www.wikidata.org/entity/Q5648512'), ('oname', 'Template:Infobox basketball club')]
# [('p', 'http://www.wikidata.org/prop/direct/P910'), ('pname', "topic's main category"), ('o', 'http://www.wikidata.org/entity/Q5647277'), ('oname', 'Category:Basketball teams')]
# 8

# %%
#From results: [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pname', 'subclass of'),
#('o', 'http://www.wikidata.org/entity/Q847017'),('oname', 'sports club')]


queryString = """
SELECT DISTINCT ?p ?pname ?o ?oname
WHERE {
   # Finding sports club properties
   wd:Q847017 ?p ?o.
   
   
   # get the label
   # ?p sc:name ?pname.
   # ?o sc:name ?oname .
}
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P2670'), ('pname', 'has parts of the class'), ('o', 'http://www.wikidata.org/entity/Q51747567'), ('oname', 'squad')]
# [('p', 'http://www.wikidata.org/prop/direct/P1343'), ('pname', 'described by source'), ('o', 'http://www.wikidata.org/entity/Q2657718'), ('oname', 'Armenian Soviet Encyclopedia')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pname', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q4438121'), ('oname', 'sports organization')]
# [('p', 'http://www.wikidata.org/prop/direct/P1424'), ('pname', "topic's main template"), ('o', 'http://www.wikidata.org/entity/Q19467997'), ('oname', 'Template:Infobox athletics club')]
# [('p', 'http://www.wikidata.org/prop/direct/P1889'), ('pname', 'different from'), ('o', 'http://www.wikidata.org/entity/Q12973014'), ('oname', 'sports team')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pname', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q988108'), ('oname', 'club')]
# [('p', 'http://www.wikidata.org/prop/direct/P910'), ('pname', "topic's main category"), ('o', 'http://www.wikidata.org/entity/Q9717774'), ('oname', 'Category:Sports clubs')]
# [('p', 'http://www.wikidata.org/prop/direct/P1424'), ('pname', "topic's main template"), ('o', 'http://www.wikidata.org/entity/Q10730006'), ('oname', 'Template:Infobox sports team')]
# [('p', 'http://www.wikidata.org/prop/direct/P1687'), ('pname', 'Wikidata property'), ('o', 'http://www.wikidata.org/entity/P4999'), ('oname', 'number of clubs')]
# 9

# %%
#[('p', 'http://www.wikidata.org/prop/direct/P279'), ('pname', 'subclass of'), 
#('o', 'http://www.wikidata.org/entity/Q4438121'), ('oname', 'sports organization')]

queryString = """
SELECT DISTINCT ?p ?pname ?o ?oname
WHERE {
   # Finding sports organization properties
   wd:Q4438121 ?p ?o.
   
   
   # get the label
   # ?p sc:name ?pname.
   # ?o sc:name ?oname .
}
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P101'), ('pname', 'field of work'), ('o', 'http://www.wikidata.org/entity/Q349'), ('oname', 'sport')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pname', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q43229'), ('oname', 'organization')]
# [('p', 'http://www.wikidata.org/prop/direct/P910'), ('pname', "topic's main category"), ('o', 'http://www.wikidata.org/entity/Q4088044'), ('oname', 'Category:Sports organizations')]
# 3

# %%
#[('p', 'http://www.wikidata.org/prop/direct/P279'), ('pname', 'subclass of'), 
#('o', 'http://www.wikidata.org/entity/Q43229'), ('oname', 'organization')]

queryString = """
SELECT DISTINCT ?p ?pname ?o ?oname
WHERE {
   # Finding organization properties
   wd:Q43229 ?p ?o.
   
   
   # get the label
   # ?p sc:name ?pname.
   # ?o sc:name ?oname .
}
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pname', 'properties for this type'), ('o', 'http://www.wikidata.org/entity/P3500'), ('oname', 'Ringgold ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pname', 'properties for this type'), ('o', 'http://www.wikidata.org/entity/P213'), ('oname', 'ISNI')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pname', 'properties for this type'), ('o', 'http://www.wikidata.org/entity/P1705'), ('oname', 'native label')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pname', 'properties for this type'), ('o', 'http://www.wikidata.org/entity/P3549'), ('oname', 'Australian Company Number')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pname', 'properties for this type'), ('o', 'http://www.wikidata.org/entity/P1278'), ('oname', 'Legal Entity Identifier')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pname', 'properties for this type'), ('o', 'http://www.wikidata.org/entity/P1320'), ('oname', 'OpenCorporates ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1889'), ('pname', 'different from'), ('o', 'http://www.wikidata.org/entity/Q36993249'), ('oname', 'arranging')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pname', 'properties for this type'), ('o', 'http://www.wikidata.org/entity/P1056'), ('oname', 'product or material produced')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pname', 'properties for this type'), ('o', 'http://www.wikidata.org/entity/P1329'), ('oname', 'phone number')]
# [('p', 'http://www.wikidata.org/prop/direct/P1552'), ('pname', 'has quality'), ('o', 'http://www.wikidata.org/entity/Q3535173'), ('oname', 'organizational life cycle')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pname', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q6671777'), ('oname', 'structure')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pname', 'properties for this type'), ('o', 'http://www.wikidata.org/entity/P159'), ('oname', 'headquarters location')]
# [('p', 'http://www.wikidata.org/prop/direct/P1552'), ('pname', 'has quality'), ('o', 'http://www.wikidata.org/entity/Q17197366'), ('oname', 'type of organisation')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pname', 'has part'), ('o', 'http://www.wikidata.org/entity/Q10756188'), ('oname', 'treasury')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pname', 'properties for this type'), ('o', 'http://www.wikidata.org/entity/P2657'), ('oname', 'EU Transparency Register ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1552'), ('pname', 'has quality'), ('o', 'http://www.wikidata.org/entity/Q730573'), ('oname', 'organizational culture')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pname', 'properties for this type'), ('o', 'http://www.wikidata.org/entity/P17'), ('oname', 'country')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pname', 'properties for this type'), ('o', 'http://www.wikidata.org/entity/P112'), ('oname', 'founded by')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pname', 'properties for this type'), ('o', 'http://www.wikidata.org/entity/P571'), ('oname', 'inception')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pname', 'properties for this type'), ('o', 'http://www.wikidata.org/entity/P1128'), ('oname', 'employees')]
# 20

# %%
#[('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pname', 'properties for this type'),
#('o', 'http://www.wikidata.org/entity/P17'), ('oname', 'country')]

#[('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pname', 'properties for this type'), 
#('o', 'http://www.wikidata.org/entity/P571'), ('oname', 'inception')]

# [('o', 'http://www.wikidata.org/entity/Q13393265'), ('oname', 'basketball team')]

queryString = """
SELECT DISTINCT ?team ?teamName ?countryName ?inception
WHERE {
   
   # set team as an instance of a basketball team
   # ?team wdt:P31 wd:Q13393265 ;
         wdt:P17 ?country ;
         wdt:P571 ?inception .
   
   
   # get the label
   # ?team sc:name ?teamName .
   # ?country sc:name ?countryName.
   
   #filtering to get all French teams with their date of inception
   
   FILTER ( REGEX (?countryName, "^[Ff]rance$") )
}
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('team', 'http://www.wikidata.org/entity/Q795707'), ('teamName', 'BCM Gravelines'), ('countryName', 'France'), ('inception', '1984-01-01T00:00:00Z')]
# [('team', 'http://www.wikidata.org/entity/Q1075934'), ('teamName', 'Cholet Basket'), ('countryName', 'France'), ('inception', '1975-01-01T00:00:00Z')]
# [('team', 'http://www.wikidata.org/entity/Q2892731'), ('teamName', 'Paris Université Club'), ('countryName', 'France'), ('inception', '1906-01-01T00:00:00Z')]
# [('team', 'http://www.wikidata.org/entity/Q404421'), ('teamName', 'STB Le Havre'), ('countryName', 'France'), ('inception', '1924-01-01T00:00:00Z')]
# [('team', 'http://www.wikidata.org/entity/Q2887227'), ('teamName', 'Basket Landes'), ('countryName', 'France'), ('inception', '2003-01-01T00:00:00Z')]
# [('team', 'http://www.wikidata.org/entity/Q40063'), ('teamName', 'Le Mans Sarthe Basket'), ('countryName', 'France'), ('inception', '1939-01-01T00:00:00Z')]
# [('team', 'http://www.wikidata.org/entity/Q2868091'), ('teamName', 'AS Monaco Basket'), ('countryName', 'France'), ('inception', '1924-01-01T00:00:00Z')]
# [('team', 'http://www.wikidata.org/entity/Q2352349'), ('teamName', 'JA Vichy'), ('countryName', 'France'), ('inception', '1933-01-01T00:00:00Z')]
# [('team', 'http://www.wikidata.org/entity/Q3178083'), ('teamName', 'JSA Bordeaux Basket'), ('countryName', 'France'), ('inception', '1938-01-01T00:00:00Z')]
# [('team', 'http://www.wikidata.org/entity/Q3532914'), ('teamName', 'Toulouse Métropole Basket'), ('countryName', 'France'), ('inception', '2008-01-01T00:00:00Z')]
# [('team', 'http://www.wikidata.org/entity/Q3549999'), ('teamName', 'LDLC ASVEL féminin'), ('countryName', 'France'), ('inception', '2000-01-01T00:00:00Z')]
# [('team', 'http://www.wikidata.org/entity/Q1076356'), ('teamName', 'Chorale Roanne Basket'), ('countryName', 'France'), ('inception', '1937-01-01T00:00:00Z')]
# [('team', 'http://www.wikidata.org/entity/Q1630650'), ('teamName', 'JL Bourg-en-Bresse'), ('countryName', 'France'), ('inception', '1910-01-01T00:00:00Z')]
# [('team', 'http://www.wikidata.org/entity/Q2819242'), ('teamName', 'ALM Évreux Basket'), ('countryName', 'France'), ('inception', '1962-01-01T00:00:00Z')]
# [('team', 'http://www.wikidata.org/entity/Q2868120'), ('teamName', 'Union Tours Basket Métropole'), ('countryName', 'France'), ('inception', '1925-01-01T00:00:00Z')]
# [('team', 'http://www.wikidata.org/entity/Q2931972'), ('teamName', 'Basket CRO Lyon'), ('countryName', 'France'), ('inception', '1927-01-01T00:00:00Z')]
# [('team', 'http://www.wikidata.org/entity/Q3237162'), ('teamName', 'Levallois Sporting Club Basket'), ('countryName', 'France'), ('inception', '1941-01-01T00:00:00Z')]
# [('team', 'http://www.wikidata.org/entity/Q3322888'), ('teamName', 'Montpellier Paillade Basket'), ('countryName', 'France'), ('inception', '1982-01-01T00:00:00Z')]
# [('team', 'http://www.wikidata.org/entity/Q3423824'), ('teamName', 'Reims Champagne Basket'), ('countryName', 'France'), ('inception', '1973-01-01T00:00:00Z')]
# [('team', 'http://www.wikidata.org/entity/Q3463255'), ('teamName', 'Saint-Quentin Basket-Ball'), ('countryName', 'France'), ('inception', '1973-01-01T00:00:00Z')]
# 20

# %% [markdown]
# Final query for this task

# %%
queryString = """
SELECT DISTINCT ?team ?teamName ( YEAR(?inception) as ?Inception ) 
WHERE {
   
   # Finding basketball team properties
   # ?team wdt:P31 wd:Q13393265 ;
         wdt:P17 ?country ;
         wdt:P571 ?inception .
   
   
   # get the label
   # ?team sc:name ?teamName .
   # ?country sc:name ?countryName.
   
   FILTER ( REGEX (?countryName, "^[Ff]rance$") )
   FILTER ( YEAR(?inception) < 1930 )
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('team', 'http://www.wikidata.org/entity/Q2892731'), ('teamName', 'Paris Université Club'), ('Inception', '1906')]
# [('team', 'http://www.wikidata.org/entity/Q404421'), ('teamName', 'STB Le Havre'), ('Inception', '1924')]
# [('team', 'http://www.wikidata.org/entity/Q2868091'), ('teamName', 'AS Monaco Basket'), ('Inception', '1924')]
# [('team', 'http://www.wikidata.org/entity/Q1630650'), ('teamName', 'JL Bourg-en-Bresse'), ('Inception', '1910')]
# [('team', 'http://www.wikidata.org/entity/Q2868120'), ('teamName', 'Union Tours Basket Métropole'), ('Inception', '1925')]
# [('team', 'http://www.wikidata.org/entity/Q2931972'), ('teamName', 'Basket CRO Lyon'), ('Inception', '1927')]
# [('team', 'http://www.wikidata.org/entity/Q2887216'), ('teamName', 'BC Orchies'), ('Inception', '1922')]
# [('team', 'http://www.wikidata.org/entity/Q3592481'), ('teamName', 'Étoile de Charleville-Mézières'), ('Inception', '1921')]
# [('team', 'http://www.wikidata.org/entity/Q638938'), ('teamName', 'Paris Basket Racing'), ('Inception', '1922')]
# [('team', 'http://www.wikidata.org/entity/Q1682230'), ('teamName', 'JDA Dijon Basket'), ('Inception', '1880')]
# [('team', 'http://www.wikidata.org/entity/Q1419876'), ('teamName', 'Limoges CSP'), ('Inception', '1929')]
# [('team', 'http://www.wikidata.org/entity/Q2737338'), ('teamName', 'SIG Basket'), ('Inception', '1928')]
# [('team', 'http://www.wikidata.org/entity/Q3550518'), ('teamName', 'Union Sportive Valenciennes Olympic'), ('Inception', '1923')]
# [('team', 'http://www.wikidata.org/entity/Q3496108'), ('teamName', 'Stade Français'), ('Inception', '1883')]
# [('team', 'http://www.wikidata.org/entity/Q1630255'), ('teamName', 'SPO Rouen Basket'), ('Inception', '1892')]
# [('team', 'http://www.wikidata.org/entity/Q1630671'), ('teamName', 'Nanterre 92'), ('Inception', '1927')]
# [('team', 'http://www.wikidata.org/entity/Q303321'), ('teamName', 'Berck BC'), ('Inception', '1929')]
# [('team', 'http://www.wikidata.org/entity/Q783067'), ('teamName', 'Alsace de Bagnolet'), ('Inception', '1908')]
# [('team', 'http://www.wikidata.org/entity/Q3134233'), ('teamName', 'Hermine de Nantes Atlantique'), ('Inception', '1891')]
# [('team', 'http://www.wikidata.org/entity/Q3459221'), ('teamName', 'Stade Auto Lyon'), ('Inception', '1916')]
# [('team', 'http://www.wikidata.org/entity/Q3351710'), ('teamName', 'Olympique Lille Basket'), ('Inception', '1924')]
# [('team', 'http://www.wikidata.org/entity/Q2955800'), ('teamName', 'Championnet Sports'), ('Inception', '1907')]
# [('team', 'http://www.wikidata.org/entity/Q3076509'), ('teamName', 'FC Grenoble'), ('Inception', '1911')]
# [('team', 'http://www.wikidata.org/entity/Q1415460'), ('teamName', 'Clermont UC'), ('Inception', '1921')]
# [('team', 'http://www.wikidata.org/entity/Q3547512'), ('teamName', 'US Métro'), ('Inception', '1928')]
# [('team', 'http://www.wikidata.org/entity/Q2930983'), ('teamName', 'CAUFA Reims'), ('Inception', '1919')]
# 26

# %% [markdown]
# ## Task 5
# Return all the NBA season (the result set must be a list of couples NBA season IRI, label)

# %%
# From Task 4 (properties for [('team', 'http://www.wikidata.org/entity/Q128109'), ('teamName', 'Chicago Bulls')] :

#[('p', 'http://www.wikidata.org/prop/direct/P118'), ('pname', 'league'), 
#('o', 'http://www.wikidata.org/entity/Q155223'), ('oname', 'National Basketball Association')]

queryString = """
SELECT DISTINCT ?p ?pname ?o ?oname
WHERE {
   # Finding National Basketball Association properties
   wd:Q155223 ?p ?o.
   
   
   # get the label
   # ?p sc:name ?pname.
   # ?o sc:name ?oname .
   
   #FILTER (REGEX(?oname , ".*season.*"))
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pname', 'instance of'), ('o', 'http://www.wikidata.org/entity/Q18536323'), ('oname', 'basketball league')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pname', 'instance of'), ('o', 'http://www.wikidata.org/entity/Q15986354'), ('oname', 'basketball association')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pname', 'has part'), ('o', 'http://www.wikidata.org/entity/Q238240'), ('oname', 'Eastern Conference')]
# [('p', 'http://www.wikidata.org/prop/direct/P1830'), ('pname', 'owner of'), ('o', 'http://www.wikidata.org/entity/Q2455323'), ('oname', 'NBA TV')]
# [('p', 'http://www.wikidata.org/prop/direct/P1365'), ('pname', 'replaces'), ('o', 'http://www.wikidata.org/entity/Q810343'), ('oname', 'Basketball Association of America')]
# [('p', 'http://www.wikidata.org/prop/direct/P6118'), ('pname', 'season ends'), ('o', 'http://www.wikidata.org/entity/Q118'), ('oname', 'April')]
# [('p', 'http://www.wikidata.org/prop/direct/P4794'), ('pname', 'season starts'), ('o', 'http://www.wikidata.org/entity/Q124'), ('oname', 'October')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pname', 'instance of'), ('o', 'http://www.wikidata.org/entity/Q15991290'), ('oname', 'professional sports league')]
# [('p', 'http://www.wikidata.org/prop/direct/P17'), ('pname', 'country'), ('o', 'http://www.wikidata.org/entity/Q16'), ('oname', 'Canada')]
# [('p', 'http://www.wikidata.org/prop/direct/P17'), ('pname', 'country'), ('o', 'http://www.wikidata.org/entity/Q30'), ('oname', 'United States of America')]
# [('p', 'http://www.wikidata.org/prop/direct/P2094'), ('pname', 'competition class'), ('o', 'http://www.wikidata.org/entity/Q46343203'), ('oname', "men's basketball")]
# [('p', 'http://www.wikidata.org/prop/direct/P641'), ('pname', 'sport'), ('o', 'http://www.wikidata.org/entity/Q5372'), ('oname', 'basketball')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pname', 'instance of'), ('o', 'http://www.wikidata.org/entity/Q7094076'), ('oname', 'online database')]
# [('p', 'http://www.wikidata.org/prop/direct/P2500'), ('pname', 'league level below'), ('o', 'http://www.wikidata.org/entity/Q842793'), ('oname', 'NBA G League')]
# [('p', 'http://www.wikidata.org/prop/direct/P1687'), ('pname', 'Wikidata property'), ('o', 'http://www.wikidata.org/entity/P3647'), ('oname', 'NBA.com player ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pname', 'winner'), ('o', 'http://www.wikidata.org/entity/Q121783'), ('oname', 'Los Angeles Lakers')]
# [('p', 'http://www.wikidata.org/prop/direct/P1830'), ('pname', 'owner of'), ('o', 'http://www.wikidata.org/entity/Q6952699'), ('oname', 'NBA Store')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pname', 'has part'), ('o', 'http://www.wikidata.org/entity/Q318389'), ('oname', 'Western Conference')]
# [('p', 'http://www.wikidata.org/prop/direct/P910'), ('pname', "topic's main category"), ('o', 'http://www.wikidata.org/entity/Q8663448'), ('oname', 'Category:National Basketball Association')]
# [('p', 'http://www.wikidata.org/prop/direct/P2500'), ('pname', 'league level below'), ('o', 'http://www.wikidata.org/entity/Q1287605'), ('oname', 'NBA Summer League')]
# [('p', 'http://www.wikidata.org/prop/direct/P1424'), ('pname', "topic's main template"), ('o', 'http://www.wikidata.org/entity/Q10950388'), ('oname', 'Template:NBA seasons')]
# [('p', 'http://www.wikidata.org/prop/direct/P1830'), ('pname', 'owner of'), ('o', 'http://www.wikidata.org/entity/Q1470803'), ('oname', 'Three-Point Contest')]
# 22

# %%
queryString = """
SELECT DISTINCT  ?inst ?instname
WHERE {
   # Finding National Basketball Association instances
   # ?inst wdt:P31 wd:Q155223 .
   
   
   # get the label
   # ?inst sc:name ?instname .
   
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# Empty

# %%
#('o', 'http://www.wikidata.org/entity/Q155223'), ('oname', 'National Basketball Association')]


queryString = """
SELECT DISTINCT ?p ?pname
WHERE {
   # trying to find related property for NBA as an object
    # ?s ?p wd:Q155223 .
   
   # get the label
   # ?p sc:name ?pname.
  
   
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P1591'), ('pname', 'defendant')]
# [('p', 'http://www.wikidata.org/prop/direct/P1423'), ('pname', 'template has topic')]
# [('p', 'http://www.wikidata.org/prop/direct/P101'), ('pname', 'field of work')]
# [('p', 'http://www.wikidata.org/prop/direct/P108'), ('pname', 'employer')]
# [('p', 'http://www.wikidata.org/prop/direct/P118'), ('pname', 'league')]
# [('p', 'http://www.wikidata.org/prop/direct/P1269'), ('pname', 'facet of')]
# [('p', 'http://www.wikidata.org/prop/direct/P127'), ('pname', 'owned by')]
# [('p', 'http://www.wikidata.org/prop/direct/P1343'), ('pname', 'described by source')]
# [('p', 'http://www.wikidata.org/prop/direct/P1366'), ('pname', 'replaced by')]
# [('p', 'http://www.wikidata.org/prop/direct/P137'), ('pname', 'operator')]
# [('p', 'http://www.wikidata.org/prop/direct/P264'), ('pname', 'record label')]
# [('p', 'http://www.wikidata.org/prop/direct/P301'), ('pname', "category's main topic")]
# [('p', 'http://www.wikidata.org/prop/direct/P3450'), ('pname', 'sports season of league or competition')]
# [('p', 'http://www.wikidata.org/prop/direct/P361'), ('pname', 'part of')]
# [('p', 'http://www.wikidata.org/prop/direct/P466'), ('pname', 'occupant')]
# [('p', 'http://www.wikidata.org/prop/direct/P664'), ('pname', 'organizer')]
# [('p', 'http://www.wikidata.org/prop/direct/P710'), ('pname', 'participant')]
# [('p', 'http://www.wikidata.org/prop/direct/P921'), ('pname', 'main subject')]
# [('p', 'http://www.wikidata.org/prop/direct/P971'), ('pname', 'category combines topics')]
# [('p', 'http://www.wikidata.org/prop/direct/P1027'), ('pname', 'conferred by')]
# [('p', 'http://www.wikidata.org/prop/direct/P2499'), ('pname', 'league level above')]
# [('p', 'http://www.wikidata.org/prop/direct/P1629'), ('pname', 'Wikidata item of this property')]
# [('p', 'http://www.wikidata.org/prop/direct/P1855'), ('pname', 'Wikidata property example')]
# [('p', 'http://www.wikidata.org/prop/direct/P9073'), ('pname', "applicable 'stated in' value")]
# 24

# %%
#From results: [('p', 'http://www.wikidata.org/prop/direct/P3450'), ('pname', 'sports season of league or competition')]

queryString = """
SELECT DISTINCT ?season ?seasonName
WHERE {
   # Finding National Basketball Association instances
    # ?season wdt:P3450 wd:Q155223 .
   
   # get the label
   # ?season sc:name ?seasonName.
  
   
}
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('season', 'http://www.wikidata.org/entity/Q600389'), ('seasonName', '1990–91 NBA season')]
# [('season', 'http://www.wikidata.org/entity/Q2264531'), ('seasonName', '1967–68 NBA season')]
# [('season', 'http://www.wikidata.org/entity/Q241834'), ('seasonName', '1989–90 NBA season')]
# [('season', 'http://www.wikidata.org/entity/Q602553'), ('seasonName', '1969–70 NBA season')]
# [('season', 'http://www.wikidata.org/entity/Q2294127'), ('seasonName', '1971–72 NBA season')]
# [('season', 'http://www.wikidata.org/entity/Q113619'), ('seasonName', '2012–13 NBA season')]
# [('season', 'http://www.wikidata.org/entity/Q16191100'), ('seasonName', '2014-15 NBA season')]
# [('season', 'http://www.wikidata.org/entity/Q19862716'), ('seasonName', '2015–16 NBA season')]
# [('season', 'http://www.wikidata.org/entity/Q631240'), ('seasonName', '1979–80 NBA season')]
# [('season', 'http://www.wikidata.org/entity/Q1142320'), ('seasonName', '2005–06 NBA season')]
# [('season', 'http://www.wikidata.org/entity/Q281094'), ('seasonName', '1949–50 NBA season')]
# [('season', 'http://www.wikidata.org/entity/Q52702755'), ('seasonName', '2018–19 NBA season')]
# [('season', 'http://www.wikidata.org/entity/Q1121549'), ('seasonName', '2007–08 NBA season')]
# [('season', 'http://www.wikidata.org/entity/Q2264502'), ('seasonName', '1961–62 NBA season')]
# [('season', 'http://www.wikidata.org/entity/Q2069853'), ('seasonName', '1983–84 NBA season')]
# [('season', 'http://www.wikidata.org/entity/Q2264540'), ('seasonName', '1975–76 NBA season')]
# [('season', 'http://www.wikidata.org/entity/Q548783'), ('seasonName', '1977–78 NBA season')]
# [('season', 'http://www.wikidata.org/entity/Q29098111'), ('seasonName', '2017–18 NBA season')]
# [('season', 'http://www.wikidata.org/entity/Q1255750'), ('seasonName', '2011–12 NBA season')]
# [('season', 'http://www.wikidata.org/entity/Q2069810'), ('seasonName', '1980–81 NBA season')]
# 20

# %% [markdown]
# Final query for this task

# %%
queryString = """
SELECT DISTINCT ?season ?seasonName
WHERE {
   # Finding National Basketball Association instances
    # ?season wdt:P3450 wd:Q155223 .
   
   # get the label
   # ?season sc:name ?seasonName.
  
   
}

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('season', 'http://www.wikidata.org/entity/Q600389'), ('seasonName', '1990–91 NBA season')]
# [('season', 'http://www.wikidata.org/entity/Q2264531'), ('seasonName', '1967–68 NBA season')]
# [('season', 'http://www.wikidata.org/entity/Q241834'), ('seasonName', '1989–90 NBA season')]
# [('season', 'http://www.wikidata.org/entity/Q602553'), ('seasonName', '1969–70 NBA season')]
# [('season', 'http://www.wikidata.org/entity/Q2294127'), ('seasonName', '1971–72 NBA season')]
# [('season', 'http://www.wikidata.org/entity/Q113619'), ('seasonName', '2012–13 NBA season')]
# [('season', 'http://www.wikidata.org/entity/Q16191100'), ('seasonName', '2014-15 NBA season')]
# [('season', 'http://www.wikidata.org/entity/Q19862716'), ('seasonName', '2015–16 NBA season')]
# [('season', 'http://www.wikidata.org/entity/Q631240'), ('seasonName', '1979–80 NBA season')]
# [('season', 'http://www.wikidata.org/entity/Q1142320'), ('seasonName', '2005–06 NBA season')]
# [('season', 'http://www.wikidata.org/entity/Q281094'), ('seasonName', '1949–50 NBA season')]
# [('season', 'http://www.wikidata.org/entity/Q52702755'), ('seasonName', '2018–19 NBA season')]
# [('season', 'http://www.wikidata.org/entity/Q1121549'), ('seasonName', '2007–08 NBA season')]
# [('season', 'http://www.wikidata.org/entity/Q2264502'), ('seasonName', '1961–62 NBA season')]
# [('season', 'http://www.wikidata.org/entity/Q2069853'), ('seasonName', '1983–84 NBA season')]
# [('season', 'http://www.wikidata.org/entity/Q2264540'), ('seasonName', '1975–76 NBA season')]
# [('season', 'http://www.wikidata.org/entity/Q548783'), ('seasonName', '1977–78 NBA season')]
# [('season', 'http://www.wikidata.org/entity/Q29098111'), ('seasonName', '2017–18 NBA season')]
# [('season', 'http://www.wikidata.org/entity/Q1255750'), ('seasonName', '2011–12 NBA season')]
# [('season', 'http://www.wikidata.org/entity/Q2069810'), ('seasonName', '1980–81 NBA season')]
# [('season', 'http://www.wikidata.org/entity/Q1132622'), ('seasonName', '2001–02 NBA season')]
# [('season', 'http://www.wikidata.org/entity/Q1132641'), ('seasonName', '1999–2000 NBA season')]
# [('season', 'http://www.wikidata.org/entity/Q1132659'), ('seasonName', '2003–04 NBA season')]
# [('season', 'http://www.wikidata.org/entity/Q1132667'), ('seasonName', '2000–01 NBA season')]
# [('season', 'http://www.wikidata.org/entity/Q1135932'), ('seasonName', '2002–03 NBA season')]
# [('season', 'http://www.wikidata.org/entity/Q1164506'), ('seasonName', '1992–93 NBA season')]
# [('season', 'http://www.wikidata.org/entity/Q1164516'), ('seasonName', '1994–95 NBA season')]
# [('season', 'http://www.wikidata.org/entity/Q1165925'), ('seasonName', '1993–94 NBA season')]
# [('season', 'http://www.wikidata.org/entity/Q1321737'), ('seasonName', '1995–96 NBA season')]
# [('season', 'http://www.wikidata.org/entity/Q1321749'), ('seasonName', '1996–97 NBA season')]
# [('season', 'http://www.wikidata.org/entity/Q1321776'), ('seasonName', '1998–99 NBA season')]
# [('season', 'http://www.wikidata.org/entity/Q925570'), ('seasonName', '1997–98 NBA season')]
# [('season', 'http://www.wikidata.org/entity/Q941115'), ('seasonName', '2004–05 NBA season')]
# [('season', 'http://www.wikidata.org/entity/Q1999389'), ('seasonName', '1952–53 NBA season')]
# [('season', 'http://www.wikidata.org/entity/Q11144228'), ('seasonName', '2013–14 NBA season')]
# [('season', 'http://www.wikidata.org/entity/Q63637259'), ('seasonName', '2019–20 NBA season')]
# [('season', 'http://www.wikidata.org/entity/Q795347'), ('seasonName', '1946–47 BAA season')]
# [('season', 'http://www.wikidata.org/entity/Q96083208'), ('seasonName', '2020–21 NBA season')]
# [('season', 'http://www.wikidata.org/entity/Q2069819'), ('seasonName', '1985–86 NBA season')]
# [('season', 'http://www.wikidata.org/entity/Q106495853'), ('seasonName', '2021–22 NBA season')]
# [('season', 'http://www.wikidata.org/entity/Q1130071'), ('seasonName', '2009–10 NBA season')]
# [('season', 'http://www.wikidata.org/entity/Q1130082'), ('seasonName', '2008–09 NBA season')]
# [('season', 'http://www.wikidata.org/entity/Q1143957'), ('seasonName', '2010–11 NBA season')]
# [('season', 'http://www.wikidata.org/entity/Q23939796'), ('seasonName', '2016–17 NBA season')]
# [('season', 'http://www.wikidata.org/entity/Q2264628'), ('seasonName', '1964–65 NBA season')]
# [('season', 'http://www.wikidata.org/entity/Q2264617'), ('seasonName', '1962–63 NBA season')]
# [('season', 'http://www.wikidata.org/entity/Q997459'), ('seasonName', '2006–07 NBA season')]
# [('season', 'http://www.wikidata.org/entity/Q389447'), ('seasonName', '1972–73 NBA season')]
# [('season', 'http://www.wikidata.org/entity/Q795353'), ('seasonName', '1948–49 BAA season')]
# [('season', 'http://www.wikidata.org/entity/Q517679'), ('seasonName', '1991–92 NBA season')]
# [('season', 'http://www.wikidata.org/entity/Q15719374'), ('seasonName', '2013 NBA Summer League')]
# [('season', 'http://www.wikidata.org/entity/Q2294141'), ('seasonName', '1966–67 NBA season')]
# [('season', 'http://www.wikidata.org/entity/Q2264581'), ('seasonName', '1973–74 NBA season')]
# [('season', 'http://www.wikidata.org/entity/Q1341019'), ('seasonName', '1988–89 NBA season')]
# [('season', 'http://www.wikidata.org/entity/Q929005'), ('seasonName', '1970–71 NBA season')]
# [('season', 'http://www.wikidata.org/entity/Q2264512'), ('seasonName', '1960–61 NBA season')]
# [('season', 'http://www.wikidata.org/entity/Q1464834'), ('seasonName', '1965–66 NBA season')]
# [('season', 'http://www.wikidata.org/entity/Q2264563'), ('seasonName', '1955–56 NBA season')]
# [('season', 'http://www.wikidata.org/entity/Q2069909'), ('seasonName', '1959–60 NBA season')]
# [('season', 'http://www.wikidata.org/entity/Q2067270'), ('seasonName', '1978–79 NBA season')]
# [('season', 'http://www.wikidata.org/entity/Q2069838'), ('seasonName', '1986–87 NBA season')]
# [('season', 'http://www.wikidata.org/entity/Q2001832'), ('seasonName', '1951–52 NBA season')]
# [('season', 'http://www.wikidata.org/entity/Q24909542'), ('seasonName', '2016 NBA Summer League')]
# [('season', 'http://www.wikidata.org/entity/Q2264593'), ('seasonName', '1968–69 NBA season')]
# [('season', 'http://www.wikidata.org/entity/Q2264605'), ('seasonName', '1957–58 NBA season')]
# [('season', 'http://www.wikidata.org/entity/Q1999363'), ('seasonName', '1950–51 NBA season')]
# [('season', 'http://www.wikidata.org/entity/Q17107932'), ('seasonName', '2012 NBA Summer League')]
# [('season', 'http://www.wikidata.org/entity/Q2264490'), ('seasonName', '1956–57 NBA season')]
# [('season', 'http://www.wikidata.org/entity/Q2264551'), ('seasonName', '1974–75 NBA season')]
# [('season', 'http://www.wikidata.org/entity/Q1986458'), ('seasonName', '1987–88 NBA season')]
# [('season', 'http://www.wikidata.org/entity/Q1986727'), ('seasonName', '1984–85 NBA season')]
# [('season', 'http://www.wikidata.org/entity/Q2069829'), ('seasonName', '1976–77 NBA season')]
# [('season', 'http://www.wikidata.org/entity/Q2067173'), ('seasonName', '1982–83 NBA season')]
# [('season', 'http://www.wikidata.org/entity/Q2264639'), ('seasonName', '1958–59 NBA season')]
# [('season', 'http://www.wikidata.org/entity/Q30646987'), ('seasonName', '2017 NBA Summer League')]
# [('season', 'http://www.wikidata.org/entity/Q2264522'), ('seasonName', '1963–64 NBA season')]
# [('season', 'http://www.wikidata.org/entity/Q2264571'), ('seasonName', '1954–55 NBA season')]
# [('season', 'http://www.wikidata.org/entity/Q1999399'), ('seasonName', '1953–54 NBA season')]
# [('season', 'http://www.wikidata.org/entity/Q2069861'), ('seasonName', '1981–82 NBA season')]
# [('season', 'http://www.wikidata.org/entity/Q795349'), ('seasonName', '1947–48 BAA season')]
# [('season', 'http://www.wikidata.org/entity/Q17001379'), ('seasonName', '2014 NBA Summer League')]
# 81

# %% [markdown]
# ## Task 6
# Consider only the basketball teams which Michael Jordan and Kobe Bryant played. Return the number of NBA seasons won by these teams (the result set must be a list of triples basketball team IRI, label and #victories. Return a number for each basketball team even if they never won a season).

# %%
#From Task 1: [('p', 'http://www.wikidata.org/prop/direct/P54'), ('name', 'member of sports team')]

queryString = """
SELECT DISTINCT ?player ?playerName ?team ?teamName
WHERE {
   
   VALUES ?player { wd:Q41421 wd:Q25369 }
   # using member of sports team property
   # ?player  wdt:P54 ?team .
   
   
   # get the label
   # ?player sc:name ?playerName .
   # ?team sc:name ?teamName .
}
LIMIT 150
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('player', 'http://www.wikidata.org/entity/Q25369'), ('playerName', 'Kobe Bryant'), ('team', 'http://www.wikidata.org/entity/Q121783'), ('teamName', 'Los Angeles Lakers')]
# [('player', 'http://www.wikidata.org/entity/Q41421'), ('playerName', 'Michael Jordan'), ('team', 'http://www.wikidata.org/entity/Q128109'), ('teamName', 'Chicago Bulls')]
# [('player', 'http://www.wikidata.org/entity/Q41421'), ('playerName', 'Michael Jordan'), ('team', 'http://www.wikidata.org/entity/Q169165'), ('teamName', 'Washington Wizards')]
# [('player', 'http://www.wikidata.org/entity/Q41421'), ('playerName', 'Michael Jordan'), ('team', 'http://www.wikidata.org/entity/Q2747877'), ('teamName', 'Birmingham Barons')]
# [('player', 'http://www.wikidata.org/entity/Q41421'), ('playerName', 'Michael Jordan'), ('team', 'http://www.wikidata.org/entity/Q3476102'), ('teamName', 'Scottsdale Scorpions')]
# [('player', 'http://www.wikidata.org/entity/Q41421'), ('playerName', 'Michael Jordan'), ('team', 'http://www.wikidata.org/entity/Q4412061'), ('teamName', "North Carolina Tar Heels men's basketball")]
# 6

# %%
#From Task 5 as an example of a season:
#[('season', 'http://www.wikidata.org/entity/Q600389'),('seasonName', '1990–91 NBA season')]

queryString = """
SELECT DISTINCT ?p ?pname ?o ?oname
WHERE {
   # Finding an NBA season properties
   wd:Q600389 ?p ?o.
   
   
   # get the label
   # ?p sc:name ?pname.
   # ?o sc:name ?oname .
}
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P910'), ('pname', "topic's main category"), ('o', 'http://www.wikidata.org/entity/Q8172698'), ('oname', 'Category:1990–91 NBA season')]
# [('p', 'http://www.wikidata.org/prop/direct/P2348'), ('pname', 'time period'), ('o', 'http://www.wikidata.org/entity/Q53389240'), ('oname', '1990-1991 one-year-period')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pname', 'instance of'), ('o', 'http://www.wikidata.org/entity/Q27020041'), ('oname', 'sports season')]
# [('p', 'http://www.wikidata.org/prop/direct/P17'), ('pname', 'country'), ('o', 'http://www.wikidata.org/entity/Q30'), ('oname', 'United States of America')]
# [('p', 'http://www.wikidata.org/prop/direct/P2094'), ('pname', 'competition class'), ('o', 'http://www.wikidata.org/entity/Q46343203'), ('oname', "men's basketball")]
# [('p', 'http://www.wikidata.org/prop/direct/P641'), ('pname', 'sport'), ('o', 'http://www.wikidata.org/entity/Q5372'), ('oname', 'basketball')]
# [('p', 'http://www.wikidata.org/prop/direct/P3450'), ('pname', 'sports season of league or competition'), ('o', 'http://www.wikidata.org/entity/Q155223'), ('oname', 'National Basketball Association')]
# [('p', 'http://www.wikidata.org/prop/direct/P664'), ('pname', 'organizer'), ('o', 'http://www.wikidata.org/entity/Q155223'), ('oname', 'National Basketball Association')]
# [('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pname', 'winner'), ('o', 'http://www.wikidata.org/entity/Q128109'), ('oname', 'Chicago Bulls')]
# 9

# %%
#From results: [('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pname', 'winner'),
#('o', 'http://www.wikidata.org/entity/Q128109'), ('oname', 'Chicago Bulls')]

queryString = """
SELECT DISTINCT ?seasonName ?teamName
WHERE {

   #All teams Jordan and Kobe played in
   VALUES ?team { wd:Q121783 wd:Q128109 wd:Q169165 wd:Q2747877 wd:Q3476102 wd:Q4412061 } 
   # all NBA seasons
   # ?season wdt:P3450 wd:Q155223 .
   
   # ?season wdt:P1346 ?team .
   
   
   # get the label
   # ?season sc:name ?seasonName .
   # ?team sc:name ?teamName .
}
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('seasonName', '1990–91 NBA season'), ('teamName', 'Chicago Bulls')]
# [('seasonName', '1971–72 NBA season'), ('teamName', 'Los Angeles Lakers')]
# [('seasonName', '1979–80 NBA season'), ('teamName', 'Los Angeles Lakers')]
# [('seasonName', '1949–50 NBA season'), ('teamName', 'Los Angeles Lakers')]
# [('seasonName', '1977–78 NBA season'), ('teamName', 'Washington Wizards')]
# [('seasonName', '2001–02 NBA season'), ('teamName', 'Los Angeles Lakers')]
# [('seasonName', '1999–2000 NBA season'), ('teamName', 'Los Angeles Lakers')]
# [('seasonName', '2000–01 NBA season'), ('teamName', 'Los Angeles Lakers')]
# [('seasonName', '1992–93 NBA season'), ('teamName', 'Chicago Bulls')]
# [('seasonName', '1995–96 NBA season'), ('teamName', 'Chicago Bulls')]
# [('seasonName', '1996–97 NBA season'), ('teamName', 'Chicago Bulls')]
# [('seasonName', '1997–98 NBA season'), ('teamName', 'Chicago Bulls')]
# [('seasonName', '1952–53 NBA season'), ('teamName', 'Los Angeles Lakers')]
# [('seasonName', '2019–20 NBA season'), ('teamName', 'Los Angeles Lakers')]
# [('seasonName', '2009–10 NBA season'), ('teamName', 'Los Angeles Lakers')]
# [('seasonName', '2008–09 NBA season'), ('teamName', 'Los Angeles Lakers')]
# [('seasonName', '1948–49 BAA season'), ('teamName', 'Los Angeles Lakers')]
# [('seasonName', '1991–92 NBA season'), ('teamName', 'Chicago Bulls')]
# [('seasonName', '1986–87 NBA season'), ('teamName', 'Los Angeles Lakers')]
# [('seasonName', '1951–52 NBA season'), ('teamName', 'Los Angeles Lakers')]
# 20

# %%
queryString = """
SELECT DISTINCT ?team ?teamName (COUNT(?season) as ?winner)
WHERE {

 
   #All teams Jordan and Kobe played in
   VALUES ?team { wd:Q121783 wd:Q128109 wd:Q169165 wd:Q2747877 wd:Q3476102 wd:Q4412061 } 

   # all NBA seasons
   # ?season wdt:P3450 wd:Q155223 .
   
   # all seasons with a winner from ?team
   # ?season wdt:P1346 ?team .
   
   # get the label
   # ?season sc:name ?seasonName .
   # ?team sc:name ?teamName .
}
GROUP BY (?team) (?teamName)
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('team', 'http://www.wikidata.org/entity/Q121783'), ('teamName', 'Los Angeles Lakers'), ('winner', '17')]
# [('team', 'http://www.wikidata.org/entity/Q169165'), ('teamName', 'Washington Wizards'), ('winner', '1')]
# [('team', 'http://www.wikidata.org/entity/Q128109'), ('teamName', 'Chicago Bulls'), ('winner', '6')]
# 3

# %%
#From Task 1: [('p', 'http://www.wikidata.org/prop/direct/P54'), ('name', 'member of sports team')]
#('o', 'http://www.wikidata.org/entity/Q155223'), ('oname', 'National Basketball Association')]
#[('x', 'http://www.wikidata.org/prop/direct/P3450'), ('xname', 'sports season of league or competition')]
#('xname', '1990–91 NBA season'), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('name', 'winner')]

queryString = """
SELECT DISTINCT  ?team ?teamName (count (?team) as ?winner)
WHERE {
    VALUES ?player {wd:Q41421  wd:Q25369}
   
    # ?player wdt:P54 ?team .
    
    optional{
    # ?season wdt:P3450 wd:Q155223.
    # ?season wdt:P1346 ?team.
    }

    # ?team sc:name ?teamName.
 
   
}
GROUP BY (?team) (?teamName)

LIMIT 20
"""
print("Results")
x=run_query(queryString)
# Out:
# Results
# [('team', 'http://www.wikidata.org/entity/Q121783'), ('teamName', 'Los Angeles Lakers'), ('winner', '17')]
# [('team', 'http://www.wikidata.org/entity/Q3476102'), ('teamName', 'Scottsdale Scorpions'), ('winner', '1')]
# [('team', 'http://www.wikidata.org/entity/Q169165'), ('teamName', 'Washington Wizards'), ('winner', '1')]
# [('team', 'http://www.wikidata.org/entity/Q128109'), ('teamName', 'Chicago Bulls'), ('winner', '6')]
# [('team', 'http://www.wikidata.org/entity/Q2747877'), ('teamName', 'Birmingham Barons'), ('winner', '1')]
# [('team', 'http://www.wikidata.org/entity/Q4412061'), ('teamName', "North Carolina Tar Heels men's basketball"), ('winner', '1')]
# 6

# %% [markdown]
# Final query for this task

# %%
queryString = """
SELECT DISTINCT ?team ?teamName (COUNT(?season) as ?winner)
WHERE {

 
   #All teams Jordan and Kobe played in
   VALUES ?team { wd:Q121783 wd:Q128109 wd:Q169165 wd:Q2747877 wd:Q3476102 wd:Q4412061 } 

   {
   # all NBA seasons
   # ?season wdt:P3450 wd:Q155223 .
   
   # all seasons with a winner from ?team
   # ?season wdt:P1346 ?team .
   
     # get the label
     # ?season sc:name ?seasonName .
     # ?team sc:name ?teamName .
   }
   UNION
   {
   
    # ?team ?p ?o .
   
     # get the label
     # ?team sc:name ?teamName .
   
   }
 
}
GROUP BY (?team) (?teamName)
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('team', 'http://www.wikidata.org/entity/Q121783'), ('teamName', 'Los Angeles Lakers'), ('winner', '17')]
# [('team', 'http://www.wikidata.org/entity/Q3476102'), ('teamName', 'Scottsdale Scorpions'), ('winner', '0')]
# [('team', 'http://www.wikidata.org/entity/Q169165'), ('teamName', 'Washington Wizards'), ('winner', '1')]
# [('team', 'http://www.wikidata.org/entity/Q128109'), ('teamName', 'Chicago Bulls'), ('winner', '6')]
# [('team', 'http://www.wikidata.org/entity/Q2747877'), ('teamName', 'Birmingham Barons'), ('winner', '0')]
# [('team', 'http://www.wikidata.org/entity/Q4412061'), ('teamName', "North Carolina Tar Heels men's basketball"), ('winner', '0')]
# 6

# %% [markdown]
# ## Task 7
# Consider only NBA (National Basketball Association) basketball teams and all basketball players who played in one of these teams at least once. Also consider the country of citizenship of the players with the related continent. Return for each continent the number of players who played in an NBA basketball teams. (the result set must be triples of continent IRI, label and #players)

# %%
#('o', 'http://www.wikidata.org/entity/Q155223'), ('oname', 'National Basketball Association')]


queryString = """
SELECT DISTINCT ?p ?pname
WHERE {
   # trying to find related property for NBA as an object
    # ?s ?p wd:Q155223 .
   
   # get the label
   # ?p sc:name ?pname.
  
   
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P1591'), ('pname', 'defendant')]
# [('p', 'http://www.wikidata.org/prop/direct/P1423'), ('pname', 'template has topic')]
# [('p', 'http://www.wikidata.org/prop/direct/P101'), ('pname', 'field of work')]
# [('p', 'http://www.wikidata.org/prop/direct/P108'), ('pname', 'employer')]
# [('p', 'http://www.wikidata.org/prop/direct/P118'), ('pname', 'league')]
# [('p', 'http://www.wikidata.org/prop/direct/P1269'), ('pname', 'facet of')]
# [('p', 'http://www.wikidata.org/prop/direct/P127'), ('pname', 'owned by')]
# [('p', 'http://www.wikidata.org/prop/direct/P1343'), ('pname', 'described by source')]
# [('p', 'http://www.wikidata.org/prop/direct/P1366'), ('pname', 'replaced by')]
# [('p', 'http://www.wikidata.org/prop/direct/P137'), ('pname', 'operator')]
# [('p', 'http://www.wikidata.org/prop/direct/P264'), ('pname', 'record label')]
# [('p', 'http://www.wikidata.org/prop/direct/P301'), ('pname', "category's main topic")]
# [('p', 'http://www.wikidata.org/prop/direct/P3450'), ('pname', 'sports season of league or competition')]
# [('p', 'http://www.wikidata.org/prop/direct/P361'), ('pname', 'part of')]
# [('p', 'http://www.wikidata.org/prop/direct/P466'), ('pname', 'occupant')]
# [('p', 'http://www.wikidata.org/prop/direct/P664'), ('pname', 'organizer')]
# [('p', 'http://www.wikidata.org/prop/direct/P710'), ('pname', 'participant')]
# [('p', 'http://www.wikidata.org/prop/direct/P921'), ('pname', 'main subject')]
# [('p', 'http://www.wikidata.org/prop/direct/P971'), ('pname', 'category combines topics')]
# [('p', 'http://www.wikidata.org/prop/direct/P1027'), ('pname', 'conferred by')]
# [('p', 'http://www.wikidata.org/prop/direct/P2499'), ('pname', 'league level above')]
# [('p', 'http://www.wikidata.org/prop/direct/P1629'), ('pname', 'Wikidata item of this property')]
# [('p', 'http://www.wikidata.org/prop/direct/P1855'), ('pname', 'Wikidata property example')]
# [('p', 'http://www.wikidata.org/prop/direct/P9073'), ('pname', "applicable 'stated in' value")]
# 24

# %%
#From results: [('p', 'http://www.wikidata.org/prop/direct/P118'), ('pname', 'league')]

## [('o', 'http://www.wikidata.org/entity/Q13393265'), ('oname', 'basketball team')]
##('o', 'http://www.wikidata.org/entity/Q155223'), ('oname', 'National Basketball Association')]


queryString = """
SELECT DISTINCT ?team ?teamName
WHERE {
   # all NBA teams
    # ?team wdt:P31 wd:Q13393265 ;
          wdt:P118 wd:Q155223 .
   
   # get the label
   # ?team sc:name ?teamName.
  
   
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('team', 'http://www.wikidata.org/entity/Q131364'), ('teamName', 'New York Knicks')]
# [('team', 'http://www.wikidata.org/entity/Q162954'), ('teamName', 'Denver Nuggets')]
# [('team', 'http://www.wikidata.org/entity/Q167253'), ('teamName', 'Portland Trail Blazers')]
# [('team', 'http://www.wikidata.org/entity/Q180950'), ('teamName', 'Oklahoma City Thunder')]
# [('team', 'http://www.wikidata.org/entity/Q976396'), ('teamName', 'Los Angeles Clippers')]
# [('team', 'http://www.wikidata.org/entity/Q166105'), ('teamName', 'Sacramento Kings')]
# [('team', 'http://www.wikidata.org/entity/Q170649'), ('teamName', 'Utah Jazz')]
# [('team', 'http://www.wikidata.org/entity/Q138089'), ('teamName', 'Philadelphia 76ers')]
# [('team', 'http://www.wikidata.org/entity/Q161345'), ('teamName', 'Houston Rockets')]
# [('team', 'http://www.wikidata.org/entity/Q164177'), ('teamName', 'Phoenix Suns')]
# [('team', 'http://www.wikidata.org/entity/Q172339'), ('teamName', 'New Orleans Pelicans')]
# [('team', 'http://www.wikidata.org/entity/Q161337'), ('teamName', 'Orlando Magic')]
# [('team', 'http://www.wikidata.org/entity/Q159729'), ('teamName', 'San Antonio Spurs')]
# [('team', 'http://www.wikidata.org/entity/Q572134'), ('teamName', 'Brooklyn Nets')]
# [('team', 'http://www.wikidata.org/entity/Q159893'), ('teamName', 'Atlanta Hawks')]
# [('team', 'http://www.wikidata.org/entity/Q169138'), ('teamName', 'Miami Heat')]
# [('team', 'http://www.wikidata.org/entity/Q3360254'), ('teamName', 'Anderson Packers')]
# [('team', 'http://www.wikidata.org/entity/Q121783'), ('teamName', 'Los Angeles Lakers')]
# [('team', 'http://www.wikidata.org/entity/Q128109'), ('teamName', 'Chicago Bulls')]
# [('team', 'http://www.wikidata.org/entity/Q157376'), ('teamName', 'Golden State Warriors')]
# [('team', 'http://www.wikidata.org/entity/Q163480'), ('teamName', 'Charlotte Hornets')]
# [('team', 'http://www.wikidata.org/entity/Q169165'), ('teamName', 'Washington Wizards')]
# [('team', 'http://www.wikidata.org/entity/Q169637'), ('teamName', 'Milwaukee Bucks')]
# [('team', 'http://www.wikidata.org/entity/Q131371'), ('teamName', 'Boston Celtics')]
# [('team', 'http://www.wikidata.org/entity/Q162990'), ('teamName', 'Cleveland Cavaliers')]
# [('team', 'http://www.wikidata.org/entity/Q165529'), ('teamName', 'Memphis Grizzlies')]
# [('team', 'http://www.wikidata.org/entity/Q132880'), ('teamName', 'Toronto Raptors')]
# [('team', 'http://www.wikidata.org/entity/Q132893'), ('teamName', 'Dallas Mavericks')]
# [('team', 'http://www.wikidata.org/entity/Q169661'), ('teamName', 'Detroit Pistons')]
# [('team', 'http://www.wikidata.org/entity/Q170558'), ('teamName', 'Minnesota Timberwolves')]
# [('team', 'http://www.wikidata.org/entity/Q170329'), ('teamName', 'Indiana Pacers')]
# [('team', 'http://www.wikidata.org/entity/Q2928124'), ('teamName', 'Baltimore Bullets')]
# [('team', 'http://www.wikidata.org/entity/Q2354728'), ('teamName', 'Sheboygan Red Skins')]
# [('team', 'http://www.wikidata.org/entity/Q513372'), ('teamName', 'Indianapolis Olympians')]
# 34

# %%
# From Task 1: [('p', 'http://www.wikidata.org/prop/direct/P54'), ('name', 'member of sports team')]
#[('job', 'http://www.wikidata.org/entity/Q3665646'), ('jobName', 'basketball player')]

queryString = """
SELECT DISTINCT ?playerName ?teamName
WHERE {
   # all NBA teams
    # ?team wdt:P31 wd:Q13393265 ;
          wdt:P118 wd:Q155223 .
   
   #all players played for an NBA team
    # ?player wdt:P31 wd:Q5 ;
            wdt:P106 wd:Q3665646 ;
            wdt:P54 ?team .
   
   # get the label
   # ?team sc:name ?teamName.
   # ?player sc:name ?playerName .
  
   
}
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('playerName', 'Bill Bradley'), ('teamName', 'New York Knicks')]
# [('playerName', 'Stephon Marbury'), ('teamName', 'New York Knicks')]
# [('playerName', 'DerMarr Johnson'), ('teamName', 'New York Knicks')]
# [('playerName', 'Jason Kidd'), ('teamName', 'New York Knicks')]
# [('playerName', 'Bruno Šundov'), ('teamName', 'New York Knicks')]
# [('playerName', 'Gene Shue'), ('teamName', 'New York Knicks')]
# [('playerName', 'Ernie Grunfeld'), ('teamName', 'New York Knicks')]
# [('playerName', 'Emmanuel Mudiay'), ('teamName', 'New York Knicks')]
# [('playerName', 'James Bailey'), ('teamName', 'New York Knicks')]
# [('playerName', 'Danilo Gallinari'), ('teamName', 'New York Knicks')]
# [('playerName', 'Sergio Rodríguez'), ('teamName', 'New York Knicks')]
# [('playerName', 'Carmelo Anthony'), ('teamName', 'New York Knicks')]
# [('playerName', 'Scott Brooks'), ('teamName', 'New York Knicks')]
# [('playerName', 'Paul Westphal'), ('teamName', 'New York Knicks')]
# [('playerName', 'Patrick Ewing'), ('teamName', 'New York Knicks')]
# [('playerName', 'Derek Harper'), ('teamName', 'New York Knicks')]
# [('playerName', 'Larry Johnson'), ('teamName', 'New York Knicks')]
# [('playerName', 'Bill Walker'), ('teamName', 'New York Knicks')]
# [('playerName', 'Charles Oakley'), ('teamName', 'New York Knicks')]
# [('playerName', 'Mark Jackson'), ('teamName', 'New York Knicks')]
# 20

# %%
queryString = """
SELECT DISTINCT ?playerName ?teamName ?countryName
WHERE {
   # all NBA teams
    # ?team wdt:P31 wd:Q13393265 ;
          wdt:P118 wd:Q155223 .
   
   #all players played for an NBA team with their nationality
    # ?player wdt:P31 wd:Q5 ;
            wdt:P106 wd:Q3665646 ;
            wdt:P54 ?team ;
            wdt:P27 ?country .
   
   # get the label
   # ?team sc:name ?teamName.
   # ?player sc:name ?playerName .
   # ?country sc:name ?countryName .
  
   
}
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('playerName', 'Ime Udoka'), ('teamName', 'New York Knicks'), ('countryName', 'Nigeria')]
# [('playerName', 'Cheikh Samb'), ('teamName', 'New York Knicks'), ('countryName', 'Senegal')]
# [('playerName', 'Mouhamed Sene'), ('teamName', 'New York Knicks'), ('countryName', 'Senegal')]
# [('playerName', 'Joakim Noah'), ('teamName', 'New York Knicks'), ('countryName', 'France')]
# [('playerName', 'Ronny Turiaf'), ('teamName', 'New York Knicks'), ('countryName', 'France')]
# [('playerName', 'Frank Ntilikina'), ('teamName', 'New York Knicks'), ('countryName', 'France')]
# [('playerName', 'Kevin Seraphin'), ('teamName', 'New York Knicks'), ('countryName', 'France')]
# [('playerName', 'Alexey Shved'), ('teamName', 'New York Knicks'), ('countryName', 'Russia')]
# [('playerName', 'Timofey Mozgov'), ('teamName', 'New York Knicks'), ('countryName', 'Russia')]
# [('playerName', 'RJ Barrett'), ('teamName', 'New York Knicks'), ('countryName', 'Canada')]
# [('playerName', 'Samuel Dalembert'), ('teamName', 'New York Knicks'), ('countryName', 'Canada')]
# [('playerName', 'Ernie Vandeweghe'), ('teamName', 'New York Knicks'), ('countryName', 'Canada')]
# [('playerName', 'Iggy Brazdeikis'), ('teamName', 'New York Knicks'), ('countryName', 'Canada')]
# [('playerName', 'Frido Frey'), ('teamName', 'New York Knicks'), ('countryName', 'Germany')]
# [('playerName', 'Kristaps Porziņģis'), ('teamName', 'New York Knicks'), ('countryName', 'Latvia')]
# [('playerName', 'Beno Udrih'), ('teamName', 'New York Knicks'), ('countryName', 'Slovenia')]
# [('playerName', 'Anthony Randolph'), ('teamName', 'New York Knicks'), ('countryName', 'Slovenia')]
# [('playerName', 'Sasha Vujačić'), ('teamName', 'New York Knicks'), ('countryName', 'Slovenia')]
# [('playerName', 'Ernie Grunfeld'), ('teamName', 'New York Knicks'), ('countryName', 'Romania')]
# [('playerName', 'Bruno Šundov'), ('teamName', 'New York Knicks'), ('countryName', 'Croatia')]
# 20

# %%
# trying to find properties related to continent 
# as an example:

queryString = """
SELECT DISTINCT ?p ?pname 
WHERE {
   # Finding country properties
   # ?person wdt:P31 wd:Q5 ;
           wdt:P27 ?country .
   # ?country ?p ?o .
   
   # get the label
   # ?p sc:name ?pname.
   # ?o sc:name ?oname .
}
LIMIT 50
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P1151'), ('pname', "topic's main Wikimedia portal")]
# [('p', 'http://www.wikidata.org/prop/direct/P122'), ('pname', 'basic form of government')]
# [('p', 'http://www.wikidata.org/prop/direct/P1269'), ('pname', 'facet of')]
# [('p', 'http://www.wikidata.org/prop/direct/P1304'), ('pname', 'central bank')]
# [('p', 'http://www.wikidata.org/prop/direct/P131'), ('pname', 'located in the administrative territorial entity')]
# [('p', 'http://www.wikidata.org/prop/direct/P1313'), ('pname', 'office held by head of government')]
# [('p', 'http://www.wikidata.org/prop/direct/P1343'), ('pname', 'described by source')]
# [('p', 'http://www.wikidata.org/prop/direct/P1365'), ('pname', 'replaces')]
# [('p', 'http://www.wikidata.org/prop/direct/P1366'), ('pname', 'replaced by')]
# [('p', 'http://www.wikidata.org/prop/direct/P138'), ('pname', 'named after')]
# [('p', 'http://www.wikidata.org/prop/direct/P140'), ('pname', 'religion')]
# [('p', 'http://www.wikidata.org/prop/direct/P1424'), ('pname', "topic's main template")]
# [('p', 'http://www.wikidata.org/prop/direct/P1464'), ('pname', 'category for people born here')]
# [('p', 'http://www.wikidata.org/prop/direct/P1465'), ('pname', 'category for people who died here')]
# [('p', 'http://www.wikidata.org/prop/direct/P150'), ('pname', 'contains administrative territorial entity')]
# [('p', 'http://www.wikidata.org/prop/direct/P155'), ('pname', 'follows')]
# [('p', 'http://www.wikidata.org/prop/direct/P1552'), ('pname', 'has quality')]
# [('p', 'http://www.wikidata.org/prop/direct/P156'), ('pname', 'followed by')]
# [('p', 'http://www.wikidata.org/prop/direct/P1589'), ('pname', 'lowest point')]
# [('p', 'http://www.wikidata.org/prop/direct/P1622'), ('pname', 'driving side')]
# [('p', 'http://www.wikidata.org/prop/direct/P163'), ('pname', 'flag')]
# [('p', 'http://www.wikidata.org/prop/direct/P17'), ('pname', 'country')]
# [('p', 'http://www.wikidata.org/prop/direct/P172'), ('pname', 'ethnic group')]
# [('p', 'http://www.wikidata.org/prop/direct/P1740'), ('pname', 'category for films shot at this location')]
# [('p', 'http://www.wikidata.org/prop/direct/P1791'), ('pname', 'category of people buried here')]
# [('p', 'http://www.wikidata.org/prop/direct/P1792'), ('pname', 'category of associated people')]
# [('p', 'http://www.wikidata.org/prop/direct/P1889'), ('pname', 'different from')]
# [('p', 'http://www.wikidata.org/prop/direct/P190'), ('pname', 'twinned administrative body')]
# [('p', 'http://www.wikidata.org/prop/direct/P1906'), ('pname', 'office held by head of state')]
# [('p', 'http://www.wikidata.org/prop/direct/P194'), ('pname', 'legislative body')]
# [('p', 'http://www.wikidata.org/prop/direct/P206'), ('pname', 'located in or next to body of water')]
# [('p', 'http://www.wikidata.org/prop/direct/P208'), ('pname', 'executive body')]
# [('p', 'http://www.wikidata.org/prop/direct/P209'), ('pname', 'highest judicial authority')]
# [('p', 'http://www.wikidata.org/prop/direct/P2184'), ('pname', 'history of topic')]
# [('p', 'http://www.wikidata.org/prop/direct/P237'), ('pname', 'coat of arms')]
# [('p', 'http://www.wikidata.org/prop/direct/P2388'), ('pname', 'office held by head of the organization')]
# [('p', 'http://www.wikidata.org/prop/direct/P2596'), ('pname', 'culture')]
# [('p', 'http://www.wikidata.org/prop/direct/P2633'), ('pname', 'geography of topic')]
# [('p', 'http://www.wikidata.org/prop/direct/P2852'), ('pname', 'emergency telephone number')]
# [('p', 'http://www.wikidata.org/prop/direct/P2853'), ('pname', 'electrical plug type')]
# [('p', 'http://www.wikidata.org/prop/direct/P2872'), ('pname', 'visitor centre')]
# [('p', 'http://www.wikidata.org/prop/direct/P2936'), ('pname', 'language used')]
# [('p', 'http://www.wikidata.org/prop/direct/P30'), ('pname', 'continent')]
# [('p', 'http://www.wikidata.org/prop/direct/P3075'), ('pname', 'official religion')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pname', 'instance of')]
# [('p', 'http://www.wikidata.org/prop/direct/P35'), ('pname', 'head of state')]
# [('p', 'http://www.wikidata.org/prop/direct/P36'), ('pname', 'capital')]
# [('p', 'http://www.wikidata.org/prop/direct/P361'), ('pname', 'part of')]
# [('p', 'http://www.wikidata.org/prop/direct/P37'), ('pname', 'official language')]
# [('p', 'http://www.wikidata.org/prop/direct/P38'), ('pname', 'currency')]
# 50

# %%
#From results: [('p', 'http://www.wikidata.org/prop/direct/P30'), ('pname', 'continent')]

queryString = """
SELECT DISTINCT ?playerName ?teamName ?countryName ?continentName
WHERE {
   # all NBA teams
    # ?team wdt:P31 wd:Q13393265 ;
          wdt:P118 wd:Q155223 .
   
   #all players played for an NBA team with their nationality
    # ?player wdt:P31 wd:Q5 ;
            wdt:P106 wd:Q3665646 ;
            wdt:P54 ?team ;
            wdt:P27 ?country .
   # continent of the player citizenship
    # ?country wdt:P30 ?continent .
   
   # get the label
   # ?team sc:name ?teamName.
   # ?player sc:name ?playerName .
   # ?country sc:name ?countryName .
   # ?continent sc:name ?continentName .
}
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('playerName', 'Ime Udoka'), ('teamName', 'New York Knicks'), ('countryName', 'Nigeria'), ('continentName', 'Africa')]
# [('playerName', 'Cheikh Samb'), ('teamName', 'New York Knicks'), ('countryName', 'Senegal'), ('continentName', 'Africa')]
# [('playerName', 'Mouhamed Sene'), ('teamName', 'New York Knicks'), ('countryName', 'Senegal'), ('continentName', 'Africa')]
# [('playerName', 'Joakim Noah'), ('teamName', 'New York Knicks'), ('countryName', 'France'), ('continentName', 'Europe')]
# [('playerName', 'Ronny Turiaf'), ('teamName', 'New York Knicks'), ('countryName', 'France'), ('continentName', 'Europe')]
# [('playerName', 'Frank Ntilikina'), ('teamName', 'New York Knicks'), ('countryName', 'France'), ('continentName', 'Europe')]
# [('playerName', 'Kevin Seraphin'), ('teamName', 'New York Knicks'), ('countryName', 'France'), ('continentName', 'Europe')]
# [('playerName', 'Alexey Shved'), ('teamName', 'New York Knicks'), ('countryName', 'Russia'), ('continentName', 'Europe')]
# [('playerName', 'Timofey Mozgov'), ('teamName', 'New York Knicks'), ('countryName', 'Russia'), ('continentName', 'Europe')]
# [('playerName', 'Frido Frey'), ('teamName', 'New York Knicks'), ('countryName', 'Germany'), ('continentName', 'Europe')]
# [('playerName', 'Kristaps Porziņģis'), ('teamName', 'New York Knicks'), ('countryName', 'Latvia'), ('continentName', 'Europe')]
# [('playerName', 'Beno Udrih'), ('teamName', 'New York Knicks'), ('countryName', 'Slovenia'), ('continentName', 'Europe')]
# [('playerName', 'Anthony Randolph'), ('teamName', 'New York Knicks'), ('countryName', 'Slovenia'), ('continentName', 'Europe')]
# [('playerName', 'Sasha Vujačić'), ('teamName', 'New York Knicks'), ('countryName', 'Slovenia'), ('continentName', 'Europe')]
# [('playerName', 'Ernie Grunfeld'), ('teamName', 'New York Knicks'), ('countryName', 'Romania'), ('continentName', 'Europe')]
# [('playerName', 'Bruno Šundov'), ('teamName', 'New York Knicks'), ('countryName', 'Croatia'), ('continentName', 'Europe')]
# [('playerName', 'Mario Hezonja'), ('teamName', 'New York Knicks'), ('countryName', 'Croatia'), ('continentName', 'Europe')]
# [('playerName', 'Sergio Rodríguez'), ('teamName', 'New York Knicks'), ('countryName', 'Spain'), ('continentName', 'Europe')]
# [('playerName', 'José Manuel Calderón'), ('teamName', 'New York Knicks'), ('countryName', 'Spain'), ('continentName', 'Europe')]
# [('playerName', 'Pablo Prigioni'), ('teamName', 'New York Knicks'), ('countryName', 'Spain'), ('continentName', 'Europe')]
# 20

# %% [markdown]
# Final query for this task

# %%
#From results: [('p', 'http://www.wikidata.org/prop/direct/P30'), ('pname', 'continent')]

queryString = """
SELECT DISTINCT ?continent ?continentName (COUNT(DISTINCT ?player) as ?players)
WHERE {
   # all NBA teams
    # ?team wdt:P31 wd:Q13393265 ;
          wdt:P118 wd:Q155223 .
   
   #all players played for an NBA team with their nationality
    # ?player wdt:P31 wd:Q5 ;
            wdt:P106 wd:Q3665646 ;
            wdt:P54 ?team ;
            wdt:P27 ?country .
   # continent of the player citizenship
    # ?country wdt:P30 ?continent .
   
   # get the label
   #?team sc:name ?teamName.
   #?player sc:name ?playerName .
   #?country sc:name ?countryName .
   # ?continent sc:name ?continentName .
}
GROUP BY (?continent) (?continentName)
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('continent', 'http://www.wikidata.org/entity/Q46'), ('continentName', 'Europe'), ('players', '300')]
# [('continent', 'http://www.wikidata.org/entity/Q538'), ('continentName', 'Insular Oceania'), ('players', '3770')]
# [('continent', 'http://www.wikidata.org/entity/Q15'), ('continentName', 'Africa'), ('players', '60')]
# [('continent', 'http://www.wikidata.org/entity/Q48'), ('continentName', 'Asia'), ('players', '73')]
# [('continent', 'http://www.wikidata.org/entity/Q5401'), ('continentName', 'Eurasia'), ('players', '17')]
# [('continent', 'http://www.wikidata.org/entity/Q18'), ('continentName', 'South America'), ('players', '37')]
# [('continent', 'http://www.wikidata.org/entity/Q49'), ('continentName', 'North America'), ('players', '3820')]
# 7

# %% [markdown]
# ## Task 8
# Identify the BGP for the NBA Defensive Player of the Year Award (see https://en.wikipedia.org/wiki/NBA_Defensive_Player_of_the_Year_Award)

# %%
#From Task 1: [('p', 'http://www.wikidata.org/prop/direct/P166'), ('name', 'award received')]


queryString = """
SELECT DISTINCT ?award ?awardName
WHERE {
   # awards received by Jordan
    wd:Q41421 wdt:P166 ?award .
   
   # get the label
   # ?award sc:name ?awardName .
  
   
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('award', 'http://www.wikidata.org/entity/Q1061233'), ('awardName', "L'Équipe Champion of Champions")]
# [('award', 'http://www.wikidata.org/entity/Q17144'), ('awardName', 'Presidential Medal of Freedom')]
# [('award', 'http://www.wikidata.org/entity/Q743122'), ('awardName', 'Associated Press Athlete of the Year')]
# [('award', 'http://www.wikidata.org/entity/Q137003'), ('awardName', '50 Greatest Players in NBA History')]
# [('award', 'http://www.wikidata.org/entity/Q1418009'), ('awardName', 'NBA All-Rookie Team')]
# [('award', 'http://www.wikidata.org/entity/Q1465181'), ('awardName', 'NBA All-Defensive Team')]
# [('award', 'http://www.wikidata.org/entity/Q1641970'), ('awardName', 'John R. Wooden Award')]
# [('award', 'http://www.wikidata.org/entity/Q1653207'), ('awardName', 'Sports Illustrated Sportsperson of the Year')]
# [('award', 'http://www.wikidata.org/entity/Q222047'), ('awardName', 'NBA Most Valuable Player Award')]
# [('award', 'http://www.wikidata.org/entity/Q2404133'), ('awardName', 'Oscar Robertson Trophy')]
# [('award', 'http://www.wikidata.org/entity/Q2666769'), ('awardName', 'Naismith College Player of the Year')]
# [('award', 'http://www.wikidata.org/entity/Q31391'), ('awardName', 'NBA All-Star Game Kobe Bryant Most Valuable Player Award')]
# [('award', 'http://www.wikidata.org/entity/Q3304648'), ('awardName', "Atlantic Coast Conference Men's Basketball Player of the Year")]
# [('award', 'http://www.wikidata.org/entity/Q4650547'), ('awardName', 'ACC Athlete of the Year')]
# [('award', 'http://www.wikidata.org/entity/Q4816371'), ('awardName', "Atlantic Coast Conference Men's Basketball Rookie of the Year")]
# [('award', 'http://www.wikidata.org/entity/Q4896614'), ('awardName', 'Best Comeback Athlete ESPY Award')]
# [('award', 'http://www.wikidata.org/entity/Q4896724'), ('awardName', 'Best Male Athlete ESPY Award')]
# [('award', 'http://www.wikidata.org/entity/Q586458'), ('awardName', 'FIBA Hall of Fame')]
# [('award', 'http://www.wikidata.org/entity/Q644357'), ('awardName', 'NBA Rookie of the Year Award')]
# [('award', 'http://www.wikidata.org/entity/Q674359'), ('awardName', 'All-NBA Team')]
# [('award', 'http://www.wikidata.org/entity/Q739499'), ('awardName', 'Bill Russell NBA Finals Most Valuable Player Award')]
# [('award', 'http://www.wikidata.org/entity/Q845884'), ('awardName', 'NBA Defensive Player of the Year Award')]
# [('award', 'http://www.wikidata.org/entity/Q943106'), ('awardName', 'Best NBA Player ESPY Award')]
# 23

# %% [markdown]
# Final query for this task

# %%
queryString = """
SELECT DISTINCT ?award ?awardName
WHERE {
   # awards received by Jordan
    wd:Q41421 wdt:P166 ?award .
   
   # get the label
   # ?award sc:name ?awardName .
  
   
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('award', 'http://www.wikidata.org/entity/Q1061233'), ('awardName', "L'Équipe Champion of Champions")]
# [('award', 'http://www.wikidata.org/entity/Q17144'), ('awardName', 'Presidential Medal of Freedom')]
# [('award', 'http://www.wikidata.org/entity/Q743122'), ('awardName', 'Associated Press Athlete of the Year')]
# [('award', 'http://www.wikidata.org/entity/Q137003'), ('awardName', '50 Greatest Players in NBA History')]
# [('award', 'http://www.wikidata.org/entity/Q1418009'), ('awardName', 'NBA All-Rookie Team')]
# [('award', 'http://www.wikidata.org/entity/Q1465181'), ('awardName', 'NBA All-Defensive Team')]
# [('award', 'http://www.wikidata.org/entity/Q1641970'), ('awardName', 'John R. Wooden Award')]
# [('award', 'http://www.wikidata.org/entity/Q1653207'), ('awardName', 'Sports Illustrated Sportsperson of the Year')]
# [('award', 'http://www.wikidata.org/entity/Q222047'), ('awardName', 'NBA Most Valuable Player Award')]
# [('award', 'http://www.wikidata.org/entity/Q2404133'), ('awardName', 'Oscar Robertson Trophy')]
# [('award', 'http://www.wikidata.org/entity/Q2666769'), ('awardName', 'Naismith College Player of the Year')]
# [('award', 'http://www.wikidata.org/entity/Q31391'), ('awardName', 'NBA All-Star Game Kobe Bryant Most Valuable Player Award')]
# [('award', 'http://www.wikidata.org/entity/Q3304648'), ('awardName', "Atlantic Coast Conference Men's Basketball Player of the Year")]
# [('award', 'http://www.wikidata.org/entity/Q4650547'), ('awardName', 'ACC Athlete of the Year')]
# [('award', 'http://www.wikidata.org/entity/Q4816371'), ('awardName', "Atlantic Coast Conference Men's Basketball Rookie of the Year")]
# [('award', 'http://www.wikidata.org/entity/Q4896614'), ('awardName', 'Best Comeback Athlete ESPY Award')]
# [('award', 'http://www.wikidata.org/entity/Q4896724'), ('awardName', 'Best Male Athlete ESPY Award')]
# [('award', 'http://www.wikidata.org/entity/Q586458'), ('awardName', 'FIBA Hall of Fame')]
# [('award', 'http://www.wikidata.org/entity/Q644357'), ('awardName', 'NBA Rookie of the Year Award')]
# [('award', 'http://www.wikidata.org/entity/Q674359'), ('awardName', 'All-NBA Team')]
# [('award', 'http://www.wikidata.org/entity/Q739499'), ('awardName', 'Bill Russell NBA Finals Most Valuable Player Award')]
# [('award', 'http://www.wikidata.org/entity/Q845884'), ('awardName', 'NBA Defensive Player of the Year Award')]
# [('award', 'http://www.wikidata.org/entity/Q943106'), ('awardName', 'Best NBA Player ESPY Award')]
# 23

# %% [markdown]
# ## Task 9
# Consider the players who won the NBA Defensive Player of the Year Award. Return for these players the number of NBA Defensive Player of the Year Award won in their career (the result set must be triples of player IRI, label and #victories)

# %%
# From Task 8: [('award', 'http://www.wikidata.org/entity/Q845884'), ('awardName', 'NBA Defensive Player of the Year Award')]

#[('job', 'http://www.wikidata.org/entity/Q3665646'), ('jobName', 'basketball player')]
#[('p', 'http://www.wikidata.org/prop/direct/P166'), ('name', 'award received')]

queryString = """
SELECT DISTINCT ?player ?playerName
WHERE {
   # All basketball players who won NBA Defensive Player of the Year Award
    # ?player wdt:P106 wd:Q3665646 ;
            wdt:P166 wd:Q845884 .
            
   
   # get the label
   # ?player sc:name ?playerName.
  
   
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('player', 'http://www.wikidata.org/entity/Q177928'), ('playerName', 'Sidney Moncrief')]
# [('player', 'http://www.wikidata.org/entity/Q310968'), ('playerName', 'Alonzo Mourning')]
# [('player', 'http://www.wikidata.org/entity/Q971538'), ('playerName', 'Michael Cooper')]
# [('player', 'http://www.wikidata.org/entity/Q189240'), ('playerName', 'Kevin Garnett')]
# [('player', 'http://www.wikidata.org/entity/Q41421'), ('playerName', 'Michael Jordan')]
# [('player', 'http://www.wikidata.org/entity/Q273256'), ('playerName', 'Hakeem Olajuwon')]
# [('player', 'http://www.wikidata.org/entity/Q211876'), ('playerName', 'David Robinson')]
# [('player', 'http://www.wikidata.org/entity/Q361134'), ('playerName', 'Marcus Camby')]
# [('player', 'http://www.wikidata.org/entity/Q295322'), ('playerName', 'Metta Sandiford-Artest')]
# [('player', 'http://www.wikidata.org/entity/Q926248'), ('playerName', 'Kawhi Leonard')]
# [('player', 'http://www.wikidata.org/entity/Q311735'), ('playerName', 'Joakim Noah')]
# [('player', 'http://www.wikidata.org/entity/Q449245'), ('playerName', 'Alvin Robertson')]
# [('player', 'http://www.wikidata.org/entity/Q201608'), ('playerName', 'Dennis Rodman')]
# [('player', 'http://www.wikidata.org/entity/Q25278'), ('playerName', 'Dwight Howard')]
# [('player', 'http://www.wikidata.org/entity/Q275889'), ('playerName', 'Marc Gasol')]
# [('player', 'http://www.wikidata.org/entity/Q295364'), ('playerName', 'Ben Wallace')]
# [('player', 'http://www.wikidata.org/entity/Q309872'), ('playerName', 'Gary Payton')]
# [('player', 'http://www.wikidata.org/entity/Q313481'), ('playerName', 'Dikembe Mutombo')]
# [('player', 'http://www.wikidata.org/entity/Q357757'), ('playerName', 'Mark Eaton')]
# [('player', 'http://www.wikidata.org/entity/Q8991894'), ('playerName', 'Giannis Antetokounmpo')]
# [('player', 'http://www.wikidata.org/entity/Q297146'), ('playerName', 'Tyson Chandler')]
# [('player', 'http://www.wikidata.org/entity/Q3446792'), ('playerName', 'Rudy Gobert')]
# 22

# %%
queryString = """
SELECT DISTINCT ?player ?playerName (COUNT(wd:Q845884) as ?DPYaward)
WHERE {
   # All basketball players who won NBA Defensive Player of the Year Award
    # ?player wdt:P106 wd:Q3665646 ;
            wdt:P166 wd:Q845884 .
            
   
   # get the label
   # ?player sc:name ?playerName.
  
   
}
GROUP BY (?player) (?playerName)
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('player', 'http://www.wikidata.org/entity/Q41421'), ('playerName', 'Michael Jordan'), ('DPYaward', '1')]
# [('player', 'http://www.wikidata.org/entity/Q357757'), ('playerName', 'Mark Eaton'), ('DPYaward', '1')]
# [('player', 'http://www.wikidata.org/entity/Q361134'), ('playerName', 'Marcus Camby'), ('DPYaward', '1')]
# [('player', 'http://www.wikidata.org/entity/Q201608'), ('playerName', 'Dennis Rodman'), ('DPYaward', '1')]
# [('player', 'http://www.wikidata.org/entity/Q3446792'), ('playerName', 'Rudy Gobert'), ('DPYaward', '1')]
# [('player', 'http://www.wikidata.org/entity/Q310968'), ('playerName', 'Alonzo Mourning'), ('DPYaward', '1')]
# [('player', 'http://www.wikidata.org/entity/Q275889'), ('playerName', 'Marc Gasol'), ('DPYaward', '1')]
# [('player', 'http://www.wikidata.org/entity/Q295322'), ('playerName', 'Metta Sandiford-Artest'), ('DPYaward', '1')]
# [('player', 'http://www.wikidata.org/entity/Q311735'), ('playerName', 'Joakim Noah'), ('DPYaward', '1')]
# [('player', 'http://www.wikidata.org/entity/Q211876'), ('playerName', 'David Robinson'), ('DPYaward', '1')]
# [('player', 'http://www.wikidata.org/entity/Q926248'), ('playerName', 'Kawhi Leonard'), ('DPYaward', '1')]
# [('player', 'http://www.wikidata.org/entity/Q25278'), ('playerName', 'Dwight Howard'), ('DPYaward', '1')]
# [('player', 'http://www.wikidata.org/entity/Q8991894'), ('playerName', 'Giannis Antetokounmpo'), ('DPYaward', '1')]
# [('player', 'http://www.wikidata.org/entity/Q309872'), ('playerName', 'Gary Payton'), ('DPYaward', '1')]
# [('player', 'http://www.wikidata.org/entity/Q297146'), ('playerName', 'Tyson Chandler'), ('DPYaward', '1')]
# [('player', 'http://www.wikidata.org/entity/Q177928'), ('playerName', 'Sidney Moncrief'), ('DPYaward', '1')]
# [('player', 'http://www.wikidata.org/entity/Q273256'), ('playerName', 'Hakeem Olajuwon'), ('DPYaward', '1')]
# [('player', 'http://www.wikidata.org/entity/Q295364'), ('playerName', 'Ben Wallace'), ('DPYaward', '1')]
# [('player', 'http://www.wikidata.org/entity/Q971538'), ('playerName', 'Michael Cooper'), ('DPYaward', '1')]
# [('player', 'http://www.wikidata.org/entity/Q189240'), ('playerName', 'Kevin Garnett'), ('DPYaward', '1')]
# [('player', 'http://www.wikidata.org/entity/Q449245'), ('playerName', 'Alvin Robertson'), ('DPYaward', '1')]
# [('player', 'http://www.wikidata.org/entity/Q313481'), ('playerName', 'Dikembe Mutombo'), ('DPYaward', '1')]
# 22

# %%
# From Task 8: [('award', 'http://www.wikidata.org/entity/Q845884'), ('awardName', 'NBA Defensive Player of the Year Award')]

queryString = """
SELECT DISTINCT ?p ?pname

WHERE {
   # NBA Defensive Player of the Year Award sub properties
    wd:Q845884 wdt:P1647 ?o .
   
   # get the label
   # ?p sc:name ?pname .
   # ?o sc:name ?oname .
  
   
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# Empty

# %%
queryString = """
SELECT ?winner ?playerName
WHERE {
   # All basketball players who won NBA Defensive Player of the Year Award
    
    wd:Q845884 wdt:P1346 ?winner.
    

            
   
   # get the label
   # ?winner sc:name ?playerName.
   #?p sc:name ?pname .
   #?o sc:name ?oname .
   
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('winner', 'http://www.wikidata.org/entity/Q177928'), ('playerName', 'Sidney Moncrief')]
# [('winner', 'http://www.wikidata.org/entity/Q310968'), ('playerName', 'Alonzo Mourning')]
# [('winner', 'http://www.wikidata.org/entity/Q971538'), ('playerName', 'Michael Cooper')]
# [('winner', 'http://www.wikidata.org/entity/Q189240'), ('playerName', 'Kevin Garnett')]
# [('winner', 'http://www.wikidata.org/entity/Q41421'), ('playerName', 'Michael Jordan')]
# [('winner', 'http://www.wikidata.org/entity/Q273256'), ('playerName', 'Hakeem Olajuwon')]
# [('winner', 'http://www.wikidata.org/entity/Q211876'), ('playerName', 'David Robinson')]
# [('winner', 'http://www.wikidata.org/entity/Q361134'), ('playerName', 'Marcus Camby')]
# [('winner', 'http://www.wikidata.org/entity/Q295322'), ('playerName', 'Metta Sandiford-Artest')]
# [('winner', 'http://www.wikidata.org/entity/Q926248'), ('playerName', 'Kawhi Leonard')]
# [('winner', 'http://www.wikidata.org/entity/Q311735'), ('playerName', 'Joakim Noah')]
# [('winner', 'http://www.wikidata.org/entity/Q449245'), ('playerName', 'Alvin Robertson')]
# [('winner', 'http://www.wikidata.org/entity/Q201608'), ('playerName', 'Dennis Rodman')]
# [('winner', 'http://www.wikidata.org/entity/Q25278'), ('playerName', 'Dwight Howard')]
# [('winner', 'http://www.wikidata.org/entity/Q275889'), ('playerName', 'Marc Gasol')]
# [('winner', 'http://www.wikidata.org/entity/Q295364'), ('playerName', 'Ben Wallace')]
# [('winner', 'http://www.wikidata.org/entity/Q309872'), ('playerName', 'Gary Payton')]
# [('winner', 'http://www.wikidata.org/entity/Q313481'), ('playerName', 'Dikembe Mutombo')]
# [('winner', 'http://www.wikidata.org/entity/Q357757'), ('playerName', 'Mark Eaton')]
# [('winner', 'http://www.wikidata.org/entity/Q297146'), ('playerName', 'Tyson Chandler')]
# 20

# %% [markdown]
# Final query for this task

# %%
"""It seems it is impossible to count the number of awards each player won without "point in time" property and we do not have access to that. no other accessible property exists to distinguish same awards with different dates or at least I could not find that."""
# Out:
# 'It seems it is impossible to count the number of awards each player won without "point in time" property and we do not have access to that. no other accessible property exists to distinguish same awards with different dates or at least I could not find that.'

# %% [markdown]
# # General instructions
#
# The goal of the project is to materialize a set of **exploratory workloads** over a real-world, large-scale,  open-domain KG: [WikiData](https://www.wikidata.org/wiki/Wikidata:Main_Page)
#
# An exploratory workload  is composed by a set of queries, where each query is related to the information obtained previously.
#
# An exploratory workload starts with a usually vague, open ended question, and does not assume the person issuing the workload has a clear understanding of the data contained in the target database or its structure.
#
# Remeber that:
#
# 1. All the queries must run in the python notebook
# 2. You can use classes and properties only if you find them via a SPARQL query that must be present in the notebook
# 3. You do not delete useless queries. Keep everything that is synthatically valid
#
# ```
# ?p <http://schema.org/name> ?name .
# ```
#
# is the BGP returning a human-readable name of a property or a class in Wikidata.

# %%
## SETUP used later

from SPARQLWrapper import SPARQLWrapper, JSON


prefixString = """
##-6981ce1fc8-##
PREFIX wd: <http://www.wikidata.org/entity/> 
PREFIX wdt: <http://www.wikidata.org/prop/direct/> 
PREFIX sc: <http://schema.org/>
"""

# select and construct queries
def run_query(queryString):
    to_run = prefixString + "\n" + queryString

    sparql = SPARQLWrapper("http://a256-gc1-02.srv.aau.dk:5820/sparql")
    sparql.setTimeout(300)
    sparql.setReturnFormat(JSON)
    sparql.setQuery(to_run)

    try :
       results = sparql.query()
       json_results = results.convert()
       if len(json_results['results']['bindings'])==0:
          print("Empty")
          return 0
    
       for bindings in json_results['results']['bindings']:
          print( [ (var, value['value'])  for var, value in bindings.items() ] )

       return len(json_results['results']['bindings'])

    except Exception as e :
        print("The operation failed", e)
    
# ASk queries
def run_ask_query(queryString):
    to_run = prefixString + "\n" + queryString

    sparql = SPARQLWrapper("http://a256-gc1-02.srv.aau.dk:5820/sparql")
    sparql.setTimeout(300)
    sparql.setReturnFormat(JSON)
    sparql.setQuery(to_run)

    try :
        return sparql.query().convert()

    except Exception as e :
        print("The operation failed", e)

# %% [markdown]
# # Sport Workflow Series ("F1 pilots explorative search")
#
# Consider the following exploratory information need:
#
# > explore F1 pilots, their nationality, racing teams, and the country of the parent organization of the team

# %% [markdown]
# ## Useful URIs for the current workflow
#
#
# The following are given:
#
# | IRI           | Description   | Role      |
# | -----------   | -----------   |-----------|
# | `wdt:P1647`   | subproperty   | predicate |
# | `wdt:P31`     | instance of   | predicate |
# | `wdt:P106`    | profession    | predicate |
# | `wdt:P279`    | subclass      | predicate |
# | `wdt:P27`     | nationality   | predicate |
# | `wdt:P17`     | country       | predicate |
# | `wd:Q10497835`| F1 Team       | node |
# | `wd:Q10841764`| F1 Driver       | node |
# | `wd:Q9671`    | Michael Schumacher      | node |
# | `wd:Q169898`  | Scuderia Ferrari         | node |
# | `wd:Q27586`   |  Ferrari         | node |
# | `wd:Q183`     | Germany       | node |
#
#
# Also consider
#
# ```
# ?p wdt:P106 wd:Q10841764 .
# ?p wdt:P27 wd:Q183 .
# ```
#
# is the BGP to retrieve all **citizens of Germany**  (driver tedeschi)
#
# ```
# ?p wdt:P17 wd:Q183 .
# ?p wdt:P31 wd:Q10497835 .
#
# ```
#
# is the BGP to retrieve all **F1 teams of Germany**

# %% [markdown]
# ## Workload Goals
#
# 1. Identify the BGP for obtaining the team of a given  F1 driver  and also the F1 competitions in which they participated
#
# 2. Identify the BGP that connects a F1 team to a parent company
#
# 3. How many F1 drivers and F1 teams exist in each country?
#
# 4. Compare number of F1 drivers to their nationality
#
#    4.1 Is there some driver that joined a team in their own country?
#
#    4.2 Which team employed the larger number of drivers?
#
#    4.3 For each country , which are the teams and drivers with the highest number of F1 race participations

# %%
# start your workflow here

# %%
queryString = """
SELECT (COUNT(?p) as ?numOfGermanDrivers)
WHERE { 

# ?p wdt:P106 wd:Q10841764 .
# ?p wdt:P27 wd:Q183 .

} 
GROUP BY ?num
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('numOfGermanDrivers', '58')]
# 1

# %% [markdown]
# Osservo tutte le proprietà dei driver (tedeschi) per vedere se trovo delle info utili. Nome del team e f1 competition

# %%
queryString = """
SELECT DISTINCT ?p ?pName
WHERE { 

# ?driver wdt:P106 wd:Q10841764 .
# ?driver wdt:P27 wd:Q183 ;
        # ?p ?obj .
        
OPTIONAL {?p <http://schema.org/name> ?pName .}

} 
ORDER BY ASC (?pName)
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('p', 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type')]
# [('p', 'http://www.wikidata.org/prop/direct-normalized/P1006')]
# [('p', 'http://www.wikidata.org/prop/direct-normalized/P1741')]
# [('p', 'http://www.wikidata.org/prop/direct-normalized/P214')]
# [('p', 'http://www.wikidata.org/prop/direct-normalized/P2163')]
# [('p', 'http://www.wikidata.org/prop/direct-normalized/P227')]
# [('p', 'http://www.wikidata.org/prop/direct-normalized/P244')]
# [('p', 'http://www.wikidata.org/prop/direct-normalized/P2671')]
# [('p', 'http://www.wikidata.org/prop/direct-normalized/P268')]
# [('p', 'http://www.wikidata.org/prop/direct-normalized/P269')]
# [('p', 'http://www.wikidata.org/prop/direct-normalized/P349')]
# [('p', 'http://www.wikidata.org/prop/direct-normalized/P434')]
# [('p', 'http://www.wikidata.org/prop/direct-normalized/P5361')]
# [('p', 'http://www.wikidata.org/prop/direct-normalized/P646')]
# [('p', 'http://schema.org/name')]
# [('p', 'http://www.wikidata.org/prop/direct/P3427'), ('pName', 'AS.com athlete ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6683'), ('pName', 'Alexander Turnbull Library ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2019'), ('pName', 'AllMovie person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1266'), ('pName', 'AlloCiné person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P4438'), ('pName', 'BFI Films, TV and people ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5361'), ('pName', 'BNB person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5007'), ('pName', 'Behind The Voice Actors person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P268'), ('pName', 'Bibliothèque nationale de France ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5019'), ('pName', 'Brockhaus Enzyklopädie online ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1273'), ('pName', 'CANTIC ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P9368'), ('pName', 'CNA topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1280'), ('pName', 'CONOR.SI ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P4666'), ('pName', 'CineMagia person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P373'), ('pName', 'Commons category')]
# [('p', 'http://www.wikidata.org/prop/direct/P935'), ('pName', 'Commons gallery')]
# [('p', 'http://www.wikidata.org/prop/direct/P6849'), ('pName', 'DR topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3509'), ('pName', 'Dagens Nyheter topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6706'), ('pName', 'De Agostini ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7902'), ('pName', 'Deutsche Biographie (GND) ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1953'), ('pName', 'Discogs artist ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3684'), ('pName', 'Driver Database driver ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1417'), ('pName', 'Encyclopædia Britannica Online ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3219'), ('pName', 'Encyclopædia Universalis ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5617'), ('pName', 'Evene ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2163'), ('pName', 'FAST ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2013'), ('pName', 'Facebook ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5254'), ('pName', 'FilmTv.it person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2639'), ('pName', 'Filmportal ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P535'), ('pName', 'Find A Grave memorial ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P646'), ('pName', 'Freebase ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7818'), ('pName', 'French Vikidia ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P227'), ('pName', 'GND ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1741'), ('pName', 'GTAA ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2600'), ('pName', 'Geni.com profile ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5247'), ('pName', 'Giant Bomb ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2671'), ('pName', 'Google Knowledge Graph ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1296'), ('pName', 'Gran Enciclopèdia Catalana ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2924'), ('pName', 'Great Russian Encyclopedia Online ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P345'), ('pName', 'IMDb ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P213'), ('pName', 'ISNI')]
# [('p', 'http://www.wikidata.org/prop/direct/P269'), ('pName', 'IdRef ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2003'), ('pName', 'Instagram username')]
# [('p', 'http://www.wikidata.org/prop/direct/P5796'), ('pName', 'Internet Game Database person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7822'), ('pName', 'Italian Vikidia ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2604'), ('pName', 'Kinopoisk person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6573'), ('pName', 'Klexikon article ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1368'), ('pName', 'LNB ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P244'), ('pName', 'Library of Congress authority ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3388'), ('pName', 'LittleSis people ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P4779'), ('pName', 'MYmovies actor ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1712'), ('pName', 'Metacritic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3913'), ('pName', 'MobyGames developer ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P4782'), ('pName', 'Movieplayer person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1285'), ('pName', 'Munzinger Sport number')]
# [('p', 'http://www.wikidata.org/prop/direct/P1284'), ('pName', 'Munzinger person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P434'), ('pName', 'MusicBrainz artist ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3222'), ('pName', 'NE.se ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P691'), ('pName', 'NKCR AUT ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1695'), ('pName', 'NLP ID (unique)')]
# [('p', 'http://www.wikidata.org/prop/direct/P1263'), ('pName', 'NNDB people ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P349'), ('pName', 'National Diet Library ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P949'), ('pName', 'National Library of Israel ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1006'), ('pName', 'Nationale Thesaurus voor Auteurs ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P9404'), ('pName', 'OFDb person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7293'), ('pName', 'PLWABN ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P4293'), ('pName', 'PM20 folder ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2435'), ('pName', 'PORT person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P9743'), ('pName', 'Podchaser creator ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8349'), ('pName', 'Proleksis enciklopedija ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3417'), ('pName', 'Quora topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7929'), ('pName', 'Roglo person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1258'), ('pName', 'Rotten Tomatoes ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3430'), ('pName', 'SNAC ARK ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8854'), ('pName', 'Salzburgwiki ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P4342'), ('pName', 'Store norske leksikon ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2168'), ('pName', 'Swedish Film Database person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P4985'), ('pName', 'TMDb person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7157'), ('pName', 'The Top Tens ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5421'), ('pName', 'Trading Card Database person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3365'), ('pName', 'Treccani ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P9775'), ('pName', "Treccani's Lessico del XXI Secolo ID")]
# [('p', 'http://www.wikidata.org/prop/direct/P2002'), ('pName', 'Twitter username')]
# [('p', 'http://www.wikidata.org/prop/direct/P214'), ('pName', 'VIAF ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2949'), ('pName', 'WikiTree person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7859'), ('pName', 'WorldCat Identities ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2397'), ('pName', 'YouTube channel ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3553'), ('pName', 'Zhihu topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P166'), ('pName', 'award received')]
# [('p', 'http://www.wikidata.org/prop/direct/P1853'), ('pName', 'blood type')]
# [('p', 'http://www.wikidata.org/prop/direct/P509'), ('pName', 'cause of death')]
# [('p', 'http://www.wikidata.org/prop/direct/P40'), ('pName', 'child')]
# [('p', 'http://www.wikidata.org/prop/direct/P4768'), ('pName', 'cinematografo.it name or company ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2094'), ('pName', 'competition class')]
# [('p', 'http://www.wikidata.org/prop/direct/P607'), ('pName', 'conflict')]
# [('p', 'http://www.wikidata.org/prop/direct/P1532'), ('pName', 'country for sport')]
# [('p', 'http://www.wikidata.org/prop/direct/P27'), ('pName', 'country of citizenship')]
# [('p', 'http://www.wikidata.org/prop/direct/P569'), ('pName', 'date of birth')]
# [('p', 'http://www.wikidata.org/prop/direct/P570'), ('pName', 'date of death')]
# [('p', 'http://www.wikidata.org/prop/direct/P1343'), ('pName', 'described by source')]
# [('p', 'http://www.wikidata.org/prop/direct/P1889'), ('pName', 'different from')]
# [('p', 'http://www.wikidata.org/prop/direct/P3927'), ('pName', 'eWRC-results.com racer ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P108'), ('pName', 'employer')]
# [('p', 'http://www.wikidata.org/prop/direct/P734'), ('pName', 'family name')]
# [('p', 'http://www.wikidata.org/prop/direct/P22'), ('pName', 'father')]
# [('p', 'http://www.wikidata.org/prop/direct/P1819'), ('pName', 'genealogics.org person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P735'), ('pName', 'given name')]
# [('p', 'http://www.wikidata.org/prop/direct/P2048'), ('pName', 'height')]
# [('p', 'http://www.wikidata.org/prop/direct/P18'), ('pName', 'image')]
# [('p', 'http://www.wikidata.org/prop/direct/P1442'), ('pName', 'image of grave')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('p', 'http://www.wikidata.org/prop/direct/P1412'), ('pName', 'languages spoken, written or signed')]
# [('p', 'http://www.wikidata.org/prop/direct/P1196'), ('pName', 'manner of death')]
# [('p', 'http://www.wikidata.org/prop/direct/P2067'), ('pName', 'mass')]
# [('p', 'http://www.wikidata.org/prop/direct/P54'), ('pName', 'member of sports team')]
# [('p', 'http://www.wikidata.org/prop/direct/P25'), ('pName', 'mother')]
# [('p', 'http://www.wikidata.org/prop/direct/P8140'), ('pName', 'motorsportstats.com driver ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P103'), ('pName', 'native language')]
# [('p', 'http://www.wikidata.org/prop/direct/P1971'), ('pName', 'number of children')]
# [('p', 'http://www.wikidata.org/prop/direct/P1350'), ('pName', 'number of matches played/races/starts')]
# [('p', 'http://www.wikidata.org/prop/direct/P106'), ('pName', 'occupation')]
# [('p', 'http://www.wikidata.org/prop/direct/P856'), ('pName', 'official website')]
# [('p', 'http://www.wikidata.org/prop/direct/P1344'), ('pName', 'participant in')]
# [('p', 'http://www.wikidata.org/prop/direct/P19'), ('pName', 'place of birth')]
# [('p', 'http://www.wikidata.org/prop/direct/P119'), ('pName', 'place of burial')]
# [('p', 'http://www.wikidata.org/prop/direct/P20'), ('pName', 'place of death')]
# [('p', 'http://www.wikidata.org/prop/direct/P39'), ('pName', 'position held')]
# [('p', 'http://www.wikidata.org/prop/direct/P443'), ('pName', 'pronunciation audio')]
# [('p', 'http://www.wikidata.org/prop/direct/P3048'), ('pName', 'racing-reference.info driver ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1038'), ('pName', 'relative')]
# [('p', 'http://www.wikidata.org/prop/direct/P551'), ('pName', 'residence')]
# [('p', 'http://www.wikidata.org/prop/direct/P21'), ('pName', 'sex or gender')]
# [('p', 'http://www.wikidata.org/prop/direct/P3373'), ('pName', 'sibling')]
# [('p', 'http://www.wikidata.org/prop/direct/P109'), ('pName', 'signature')]
# [('p', 'http://www.wikidata.org/prop/direct/P793'), ('pName', 'significant event')]
# [('p', 'http://www.wikidata.org/prop/direct/P8687'), ('pName', 'social media followers')]
# [('p', 'http://www.wikidata.org/prop/direct/P641'), ('pName', 'sport')]
# [('p', 'http://www.wikidata.org/prop/direct/P26'), ('pName', 'spouse')]
# [('p', 'http://www.wikidata.org/prop/direct/P2868'), ('pName', 'subject has role')]
# [('p', 'http://www.wikidata.org/prop/direct/P910'), ('pName', "topic's main category")]
# [('p', 'http://www.wikidata.org/prop/direct/P6544'), ('pName', 'total points in career')]
# [('p', 'http://www.wikidata.org/prop/direct/P2522'), ('pName', 'victory')]
# [('p', 'http://www.wikidata.org/prop/direct/P937'), ('pName', 'work location')]
# [('p', 'http://www.wikidata.org/prop/direct/P2605'), ('pName', 'ČSFD person ID')]
# 158

# %% [markdown]
# ho trovato come interessanti:
#
# P2094 "competition class" <br>
# P108 "employer" <br>
# P54 "member of sport team" <br>
# P1344 "partecipant in" <br>
# P735 "given name" <br>
#
# Explore the property for a german driver. First of all I search for a german driver.

# %%
queryString = """
SELECT DISTINCT ?driver ?dName
WHERE { 

# ?driver wdt:P106 wd:Q10841764 .
# ?driver wdt:P27 wd:Q183 .
        
OPTIONAL {?driver <http://schema.org/name> ?dName .}

} 
LIMIT 10
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('driver', 'http://www.wikidata.org/entity/Q49235'), ('dName', 'Adrian Sutil')]
# [('driver', 'http://www.wikidata.org/entity/Q57459'), ('dName', 'Jochen Mass')]
# [('driver', 'http://www.wikidata.org/entity/Q58654'), ('dName', 'Hans-Joachim Stuck')]
# [('driver', 'http://www.wikidata.org/entity/Q61295'), ('dName', 'Theo Helfrich')]
# [('driver', 'http://www.wikidata.org/entity/Q61541'), ('dName', 'Hans Stuck')]
# [('driver', 'http://www.wikidata.org/entity/Q75810'), ('dName', 'Nick Heidfeld')]
# [('driver', 'http://www.wikidata.org/entity/Q2165501'), ('dName', 'Adolf Lang')]
# [('driver', 'http://www.wikidata.org/entity/Q57451'), ('dName', 'Wolfgang von Trips')]
# [('driver', 'http://www.wikidata.org/entity/Q2253423'), ('dName', 'Ludwig Fischer')]
# [('driver', 'http://www.wikidata.org/entity/Q42311'), ('dName', 'Sebastian Vettel')]
# 10

# %% [markdown]
# sebastian vettel "Q42311". Usin the previous properties

# %%
queryString = """
SELECT ?compClass ?cName ?employer ?eName ?member ?mName ?partIn ?pName
WHERE { 

wd:Q42311 wdt:P2094 ?compClass ;
            wdt:P108 ?employer ;
            wdt:P54 ?member ;
            wdt:P1344 ?partIn .
        
OPTIONAL {?compClass <http://schema.org/name> ?cName .
            # ?employer <http://schema.org/name> ?eName .
            # ?member <http://schema.org/name> ?mName .
            # ?partIn <http://schema.org/name> ?pName .

}

} 

"""

print("Results")
run_query(queryString)
# Out:
# Results
# Empty
# 0

# %%
#non va? 
queryString = """
SELECT ?p ?pName ?obj ?objName
WHERE { 

wd:Q42311 ?p ?obj .
        
OPTIONAL {?p <http://schema.org/name> ?pName .}
OPTIONAL{?obj <http://schema.org/name> ?objName .}

} 
ORDER BY ASC (?pName)
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('p', 'http://schema.org/name'), ('obj', 'Sebastian Vettel')]
# [('p', 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), ('obj', 'http://wikiba.se/ontology#Item')]
# [('p', 'http://www.wikidata.org/prop/direct-normalized/P1741'), ('obj', 'http://data.beeldengeluid.nl/gtaa/225470')]
# [('p', 'http://www.wikidata.org/prop/direct-normalized/P214'), ('obj', 'http://viaf.org/viaf/120235751')]
# [('p', 'http://www.wikidata.org/prop/direct-normalized/P2163'), ('obj', 'http://id.worldcat.org/fast/1955448')]
# [('p', 'http://www.wikidata.org/prop/direct-normalized/P227'), ('obj', 'https://d-nb.info/gnd/140974741')]
# [('p', 'http://www.wikidata.org/prop/direct-normalized/P244'), ('obj', 'https://id.loc.gov/authorities/names/no2012112192')]
# [('p', 'http://www.wikidata.org/prop/direct-normalized/P646'), ('obj', 'http://g.co/kg/m/0g5brh')]
# [('p', 'http://www.wikidata.org/prop/direct/P3427'), ('pName', 'AS.com athlete ID'), ('obj', 'sebastian_vettel/24343')]
# [('p', 'http://www.wikidata.org/prop/direct/P6683'), ('pName', 'Alexander Turnbull Library ID'), ('obj', '299038')]
# [('p', 'http://www.wikidata.org/prop/direct/P5007'), ('pName', 'Behind The Voice Actors person ID'), ('obj', 'Sebastian-Vettel')]
# [('p', 'http://www.wikidata.org/prop/direct/P5019'), ('pName', 'Brockhaus Enzyklopädie online ID'), ('obj', 'vettel-sebastian')]
# [('p', 'http://www.wikidata.org/prop/direct/P9368'), ('pName', 'CNA topic ID'), ('obj', 'sebastian-vettel')]
# [('p', 'http://www.wikidata.org/prop/direct/P4666'), ('pName', 'CineMagia person ID'), ('obj', '536328')]
# [('p', 'http://www.wikidata.org/prop/direct/P373'), ('pName', 'Commons category'), ('obj', 'Sebastian Vettel')]
# [('p', 'http://www.wikidata.org/prop/direct/P935'), ('pName', 'Commons gallery'), ('obj', 'Sebastian Vettel')]
# [('p', 'http://www.wikidata.org/prop/direct/P6706'), ('pName', 'De Agostini ID'), ('obj', 'Vettel,+Sebastian')]
# [('p', 'http://www.wikidata.org/prop/direct/P7902'), ('pName', 'Deutsche Biographie (GND) ID'), ('obj', '140974741')]
# [('p', 'http://www.wikidata.org/prop/direct/P3684'), ('pName', 'Driver Database driver ID'), ('obj', 'sebastian-vettel')]
# [('p', 'http://www.wikidata.org/prop/direct/P1417'), ('pName', 'Encyclopædia Britannica Online ID'), ('obj', 'biography/Sebastian-Vettel')]
# [('p', 'http://www.wikidata.org/prop/direct/P3219'), ('pName', 'Encyclopædia Universalis ID'), ('obj', 'sebastian-vettel')]
# [('p', 'http://www.wikidata.org/prop/direct/P2163'), ('pName', 'FAST ID'), ('obj', '1955448')]
# [('p', 'http://www.wikidata.org/prop/direct/P5254'), ('pName', 'FilmTv.it person ID'), ('obj', '160062')]
# [('p', 'http://www.wikidata.org/prop/direct/P646'), ('pName', 'Freebase ID'), ('obj', '/m/0g5brh')]
# [('p', 'http://www.wikidata.org/prop/direct/P227'), ('pName', 'GND ID'), ('obj', '140974741')]
# [('p', 'http://www.wikidata.org/prop/direct/P1741'), ('pName', 'GTAA ID'), ('obj', '225470')]
# [('p', 'http://www.wikidata.org/prop/direct/P5247'), ('pName', 'Giant Bomb ID'), ('obj', '3005-16677')]
# [('p', 'http://www.wikidata.org/prop/direct/P1296'), ('pName', 'Gran Enciclopèdia Catalana ID'), ('obj', '0520642')]
# [('p', 'http://www.wikidata.org/prop/direct/P2924'), ('pName', 'Great Russian Encyclopedia Online ID'), ('obj', '4710323')]
# [('p', 'http://www.wikidata.org/prop/direct/P345'), ('pName', 'IMDb ID'), ('obj', 'nm2697599')]
# [('p', 'http://www.wikidata.org/prop/direct/P213'), ('pName', 'ISNI'), ('obj', '0000 0000 7787 8795')]
# [('p', 'http://www.wikidata.org/prop/direct/P5796'), ('pName', 'Internet Game Database person ID'), ('obj', 'sebastian-vettel')]
# [('p', 'http://www.wikidata.org/prop/direct/P6573'), ('pName', 'Klexikon article ID'), ('obj', 'Sebastian_Vettel')]
# [('p', 'http://www.wikidata.org/prop/direct/P244'), ('pName', 'Library of Congress authority ID'), ('obj', 'no2012112192')]
# [('p', 'http://www.wikidata.org/prop/direct/P3388'), ('pName', 'LittleSis people ID'), ('obj', '264106')]
# [('p', 'http://www.wikidata.org/prop/direct/P1712'), ('pName', 'Metacritic ID'), ('obj', 'person/sebastian-vettel')]
# [('p', 'http://www.wikidata.org/prop/direct/P3913'), ('pName', 'MobyGames developer ID'), ('obj', '831148')]
# [('p', 'http://www.wikidata.org/prop/direct/P4782'), ('pName', 'Movieplayer person ID'), ('obj', '362516')]
# [('p', 'http://www.wikidata.org/prop/direct/P1285'), ('pName', 'Munzinger Sport number'), ('obj', '01000007208')]
# [('p', 'http://www.wikidata.org/prop/direct/P3222'), ('pName', 'NE.se ID'), ('obj', 'sebastian-vettel')]
# [('p', 'http://www.wikidata.org/prop/direct/P8349'), ('pName', 'Proleksis enciklopedija ID'), ('obj', '152117')]
# [('p', 'http://www.wikidata.org/prop/direct/P3417'), ('pName', 'Quora topic ID'), ('obj', 'Sebastian-Vettel')]
# [('p', 'http://www.wikidata.org/prop/direct/P1258'), ('pName', 'Rotten Tomatoes ID'), ('obj', 'celebrity/sebastian_vettel')]
# [('p', 'http://www.wikidata.org/prop/direct/P4342'), ('pName', 'Store norske leksikon ID'), ('obj', 'Sebastian_Vettel')]
# [('p', 'http://www.wikidata.org/prop/direct/P4985'), ('pName', 'TMDb person ID'), ('obj', '1443760')]
# [('p', 'http://www.wikidata.org/prop/direct/P5421'), ('pName', 'Trading Card Database person ID'), ('obj', '78152')]
# [('p', 'http://www.wikidata.org/prop/direct/P3365'), ('pName', 'Treccani ID'), ('obj', 'sebastian-vettel')]
# [('p', 'http://www.wikidata.org/prop/direct/P214'), ('pName', 'VIAF ID'), ('obj', '120235751')]
# [('p', 'http://www.wikidata.org/prop/direct/P7859'), ('pName', 'WorldCat Identities ID'), ('obj', 'lccn-no2012112192')]
# [('p', 'http://www.wikidata.org/prop/direct/P166'), ('pName', 'award received'), ('obj', 'http://www.wikidata.org/entity/Q315026'), ('objName', 'Silbernes Lorbeerblatt')]
# [('p', 'http://www.wikidata.org/prop/direct/P166'), ('pName', 'award received'), ('obj', 'http://www.wikidata.org/entity/Q876882'), ('objName', 'German Sportspersonality of the Year')]
# [('p', 'http://www.wikidata.org/prop/direct/P4768'), ('pName', 'cinematografo.it name or company ID'), ('obj', '325368')]
# [('p', 'http://www.wikidata.org/prop/direct/P1532'), ('pName', 'country for sport'), ('obj', 'http://www.wikidata.org/entity/Q183'), ('objName', 'Germany')]
# [('p', 'http://www.wikidata.org/prop/direct/P27'), ('pName', 'country of citizenship'), ('obj', 'http://www.wikidata.org/entity/Q183'), ('objName', 'Germany')]
# [('p', 'http://www.wikidata.org/prop/direct/P569'), ('pName', 'date of birth'), ('obj', '1987-07-03T00:00:00Z')]
# [('p', 'http://www.wikidata.org/prop/direct/P734'), ('pName', 'family name'), ('obj', 'http://www.wikidata.org/entity/Q37495205'), ('objName', 'Vettel')]
# [('p', 'http://www.wikidata.org/prop/direct/P1819'), ('pName', 'genealogics.org person ID'), ('obj', 'I00751523')]
# [('p', 'http://www.wikidata.org/prop/direct/P735'), ('pName', 'given name'), ('obj', 'http://www.wikidata.org/entity/Q4844560'), ('objName', 'Sebastian')]
# [('p', 'http://www.wikidata.org/prop/direct/P2048'), ('pName', 'height'), ('obj', '176')]
# [('p', 'http://www.wikidata.org/prop/direct/P18'), ('pName', 'image'), ('obj', 'http://commons.wikimedia.org/wiki/Special:FilePath/2019%20Formula%20One%20tests%20Barcelona%2C%20Vettel%20%2847200008782%29.jpg')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q5'), ('objName', 'human')]
# [('p', 'http://www.wikidata.org/prop/direct/P1412'), ('pName', 'languages spoken, written or signed'), ('obj', 'http://www.wikidata.org/entity/Q188'), ('objName', 'German')]
# [('p', 'http://www.wikidata.org/prop/direct/P2067'), ('pName', 'mass'), ('obj', '62')]
# [('p', 'http://www.wikidata.org/prop/direct/P54'), ('pName', 'member of sports team'), ('obj', 'http://www.wikidata.org/entity/Q173663'), ('objName', 'Red Bull Racing')]
# [('p', 'http://www.wikidata.org/prop/direct/P54'), ('pName', 'member of sports team'), ('obj', 'http://www.wikidata.org/entity/Q750016'), ('objName', 'Aston Martin Racing')]
# [('p', 'http://www.wikidata.org/prop/direct/P54'), ('pName', 'member of sports team'), ('obj', 'http://www.wikidata.org/entity/Q141818'), ('objName', 'Scuderia Toro Rosso')]
# [('p', 'http://www.wikidata.org/prop/direct/P54'), ('pName', 'member of sports team'), ('obj', 'http://www.wikidata.org/entity/Q154118'), ('objName', 'BMW Sauber')]
# [('p', 'http://www.wikidata.org/prop/direct/P54'), ('pName', 'member of sports team'), ('obj', 'http://www.wikidata.org/entity/Q169898'), ('objName', 'Scuderia Ferrari')]
# [('p', 'http://www.wikidata.org/prop/direct/P8140'), ('pName', 'motorsportstats.com driver ID'), ('obj', 'sebastian-vettel')]
# [('p', 'http://www.wikidata.org/prop/direct/P103'), ('pName', 'native language'), ('obj', 'http://www.wikidata.org/entity/Q188'), ('objName', 'German')]
# [('p', 'http://www.wikidata.org/prop/direct/P1971'), ('pName', 'number of children'), ('obj', '3')]
# [('p', 'http://www.wikidata.org/prop/direct/P106'), ('pName', 'occupation'), ('obj', 'http://www.wikidata.org/entity/Q10841764'), ('objName', 'Formula One driver')]
# [('p', 'http://www.wikidata.org/prop/direct/P106'), ('pName', 'occupation'), ('obj', 'http://www.wikidata.org/entity/Q30339659'), ('objName', 'motorsports competitor')]
# [('p', 'http://www.wikidata.org/prop/direct/P106'), ('pName', 'occupation'), ('obj', 'http://www.wikidata.org/entity/Q10349745'), ('objName', 'racing automobile driver')]
# [('p', 'http://www.wikidata.org/prop/direct/P856'), ('pName', 'official website'), ('obj', 'http://www.sebastianvettel.de/')]
# [('p', 'http://www.wikidata.org/prop/direct/P19'), ('pName', 'place of birth'), ('obj', 'http://www.wikidata.org/entity/Q524407'), ('objName', 'Heppenheim')]
# [('p', 'http://www.wikidata.org/prop/direct/P443'), ('pName', 'pronunciation audio'), ('obj', 'http://commons.wikimedia.org/wiki/Special:FilePath/De-Sebastian-Vettel.ogg')]
# [('p', 'http://www.wikidata.org/prop/direct/P3048'), ('pName', 'racing-reference.info driver ID'), ('obj', 'Sebastian_Vettel')]
# [('p', 'http://www.wikidata.org/prop/direct/P21'), ('pName', 'sex or gender'), ('obj', 'http://www.wikidata.org/entity/Q6581097'), ('objName', 'male')]
# [('p', 'http://www.wikidata.org/prop/direct/P109'), ('pName', 'signature'), ('obj', 'http://commons.wikimedia.org/wiki/Special:FilePath/Tanda%20Tangan%20Sebastian%20Vettel.svg')]
# [('p', 'http://www.wikidata.org/prop/direct/P641'), ('pName', 'sport'), ('obj', 'http://www.wikidata.org/entity/Q3077544'), ('objName', 'Formula Renault 3.5 Series')]
# [('p', 'http://www.wikidata.org/prop/direct/P641'), ('pName', 'sport'), ('obj', 'http://www.wikidata.org/entity/Q1003026'), ('objName', 'Formula 3 Euro Series')]
# [('p', 'http://www.wikidata.org/prop/direct/P641'), ('pName', 'sport'), ('obj', 'http://www.wikidata.org/entity/Q1968'), ('objName', 'Formula One')]
# [('p', 'http://www.wikidata.org/prop/direct/P641'), ('pName', 'sport'), ('obj', 'http://www.wikidata.org/entity/Q1343487'), ('objName', 'Formula BMW')]
# [('p', 'http://www.wikidata.org/prop/direct/P910'), ('pName', "topic's main category"), ('obj', 'http://www.wikidata.org/entity/Q15722972'), ('objName', 'Category:Sebastian Vettel')]
# [('p', 'http://www.wikidata.org/prop/direct/P2522'), ('pName', 'victory'), ('obj', 'http://www.wikidata.org/entity/Q69959'), ('objName', '2012 Formula One World Championship')]
# [('p', 'http://www.wikidata.org/prop/direct/P2522'), ('pName', 'victory'), ('obj', 'http://www.wikidata.org/entity/Q69356'), ('objName', '2013 Formula One World Championship')]
# [('p', 'http://www.wikidata.org/prop/direct/P2522'), ('pName', 'victory'), ('obj', 'http://www.wikidata.org/entity/Q69943'), ('objName', '2011 Formula One World Championship')]
# [('p', 'http://www.wikidata.org/prop/direct/P2522'), ('pName', 'victory'), ('obj', 'http://www.wikidata.org/entity/Q69934'), ('objName', '2010 Formula One World Championship')]
# 89

# %% [markdown]
# Vettel non ha tutte le proprietà precedenti... solo alcune
#
# "Identify the BGP for obtaining the team of a given  F1 driver  and also the F1 competitions in which they participated"
#
# Q10841764 "F1 driver" f1 driver category

# %%
queryString = """
SELECT ?p ?pName ?obj ?objName
WHERE { 

wd:Q10841764 ?p ?obj .
        
OPTIONAL {?p <http://schema.org/name> ?pName .}
OPTIONAL{?obj <http://schema.org/name> ?objName .}
} 
ORDER BY ASC (?pName)
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('p', 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), ('obj', 'http://wikiba.se/ontology#Item')]
# [('p', 'http://www.wikidata.org/prop/direct-normalized/P8408'), ('obj', 'http://kbpedia.org/kko/rc/FormulaOneRacer')]
# [('p', 'http://schema.org/name'), ('obj', 'Formula One driver')]
# [('p', 'http://www.wikidata.org/prop/direct/P8408'), ('pName', 'KBpedia ID'), ('obj', 'FormulaOneRacer')]
# [('p', 'http://www.wikidata.org/prop/direct/P425'), ('pName', 'field of this occupation'), ('obj', 'http://www.wikidata.org/entity/Q1968'), ('objName', 'Formula One')]
# [('p', 'http://www.wikidata.org/prop/direct/P2354'), ('pName', 'has list'), ('obj', 'http://www.wikidata.org/entity/Q172853'), ('objName', 'list of Formula One drivers')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q28640'), ('objName', 'profession')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('obj', 'http://www.wikidata.org/entity/Q10349745'), ('objName', 'racing automobile driver')]
# [('p', 'http://www.wikidata.org/prop/direct/P910'), ('pName', "topic's main category"), ('obj', 'http://www.wikidata.org/entity/Q7217610'), ('objName', 'Category:Formula One drivers')]
# [('p', 'http://www.wikidata.org/prop/direct/P1424'), ('pName', "topic's main template"), ('obj', 'http://www.wikidata.org/entity/Q6062107'), ('objName', 'Template:Infobox F1 driver')]
# 10

# %% [markdown]
# Esploro F1 Q1968 in cerca di qualcosa legato alle edizioni

# %%
queryString = """
SELECT ?p ?pName ?obj ?objName
WHERE { 

wd:Q1968 ?p ?obj .
        
OPTIONAL {?p <http://schema.org/name> ?pName .}
OPTIONAL{?obj <http://schema.org/name> ?objName .}
} 
ORDER BY ASC (?pName)
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('p', 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), ('obj', 'http://wikiba.se/ontology#Item')]
# [('p', 'http://www.wikidata.org/prop/direct-normalized/P214'), ('obj', 'http://viaf.org/viaf/245922962')]
# [('p', 'http://www.wikidata.org/prop/direct-normalized/P227'), ('obj', 'https://d-nb.info/gnd/4267570-4')]
# [('p', 'http://www.wikidata.org/prop/direct-normalized/P244'), ('obj', 'https://id.loc.gov/authorities/names/nb2012002495')]
# [('p', 'http://www.wikidata.org/prop/direct-normalized/P268'), ('obj', 'http://data.bnf.fr/ark:/12148/cb12002946q#about')]
# [('p', 'http://www.wikidata.org/prop/direct-normalized/P349'), ('obj', 'http://id.ndl.go.jp/auth/ndlna/00960053')]
# [('p', 'http://www.wikidata.org/prop/direct-normalized/P5429'), ('obj', 'http://cv.iptc.org/newscodes/mediatopic/20000994')]
# [('p', 'http://www.wikidata.org/prop/direct-normalized/P646'), ('obj', 'http://g.co/kg/m/02xz2')]
# [('p', 'http://schema.org/name'), ('obj', 'Formula One')]
# [('p', 'http://www.wikidata.org/prop/direct/P268'), ('pName', 'Bibliothèque nationale de France ID'), ('obj', '12002946q')]
# [('p', 'http://www.wikidata.org/prop/direct/P9368'), ('pName', 'CNA topic ID'), ('obj', 'formula-1')]
# [('p', 'http://www.wikidata.org/prop/direct/P373'), ('pName', 'Commons category'), ('obj', 'Formula One')]
# [('p', 'http://www.wikidata.org/prop/direct/P935'), ('pName', 'Commons gallery'), ('obj', 'Formula One')]
# [('p', 'http://www.wikidata.org/prop/direct/P3509'), ('pName', 'Dagens Nyheter topic ID'), ('obj', 'formel-1')]
# [('p', 'http://www.wikidata.org/prop/direct/P1417'), ('pName', 'Encyclopædia Britannica Online ID'), ('obj', 'sports/Formula-One-automobile-racing')]
# [('p', 'http://www.wikidata.org/prop/direct/P3219'), ('pName', 'Encyclopædia Universalis ID'), ('obj', 'formule-1')]
# [('p', 'http://www.wikidata.org/prop/direct/P2013'), ('pName', 'Facebook ID'), ('obj', 'Formula1')]
# [('p', 'http://www.wikidata.org/prop/direct/P6262'), ('pName', 'Fandom article ID'), ('obj', 'world-sports-results:Formula_1')]
# [('p', 'http://www.wikidata.org/prop/direct/P646'), ('pName', 'Freebase ID'), ('obj', '/m/02xz2')]
# [('p', 'http://www.wikidata.org/prop/direct/P7818'), ('pName', 'French Vikidia ID'), ('obj', 'Formule_1')]
# [('p', 'http://www.wikidata.org/prop/direct/P227'), ('pName', 'GND ID'), ('obj', '4267570-4')]
# [('p', 'http://www.wikidata.org/prop/direct/P3106'), ('pName', 'Guardian topic ID'), ('obj', 'sport/formulaone')]
# [('p', 'http://www.wikidata.org/prop/direct/P5429'), ('pName', 'IPTC NewsCode'), ('obj', 'mediatopic/20000994')]
# [('p', 'http://www.wikidata.org/prop/direct/P2003'), ('pName', 'Instagram username'), ('obj', 'f1')]
# [('p', 'http://www.wikidata.org/prop/direct/P7822'), ('pName', 'Italian Vikidia ID'), ('obj', 'Formula_1')]
# [('p', 'http://www.wikidata.org/prop/direct/P6573'), ('pName', 'Klexikon article ID'), ('obj', 'Formel_1')]
# [('p', 'http://www.wikidata.org/prop/direct/P244'), ('pName', 'Library of Congress authority ID'), ('obj', 'nb2012002495')]
# [('p', 'http://www.wikidata.org/prop/direct/P691'), ('pName', 'NKCR AUT ID'), ('obj', 'kn20061004005')]
# [('p', 'http://www.wikidata.org/prop/direct/P349'), ('pName', 'National Diet Library ID'), ('obj', '00960053')]
# [('p', 'http://www.wikidata.org/prop/direct/P3221'), ('pName', 'New York Times topic ID'), ('obj', 'organization/formula-one')]
# [('p', 'http://www.wikidata.org/prop/direct/P6900'), ('pName', 'NicoNicoPedia ID'), ('obj', 'f1世界選手権')]
# [('p', 'http://www.wikidata.org/prop/direct/P3417'), ('pName', 'Quora topic ID'), ('obj', 'Formula-1-1')]
# [('p', 'http://www.wikidata.org/prop/direct/P7827'), ('pName', 'Spanish Vikidia ID'), ('obj', 'Fórmula_1')]
# [('p', 'http://www.wikidata.org/prop/direct/P7157'), ('pName', 'The Top Tens ID'), ('obj', '288')]
# [('p', 'http://www.wikidata.org/prop/direct/P3365'), ('pName', 'Treccani ID'), ('obj', 'formula-1')]
# [('p', 'http://www.wikidata.org/prop/direct/P3365'), ('pName', 'Treccani ID'), ('obj', "formula-1_(Il-Libro-dell'Anno)")]
# [('p', 'http://www.wikidata.org/prop/direct/P8672'), ('pName', 'Twitter topic ID'), ('obj', '854701577994616832')]
# [('p', 'http://www.wikidata.org/prop/direct/P2002'), ('pName', 'Twitter username'), ('obj', 'F1')]
# [('p', 'http://www.wikidata.org/prop/direct/P214'), ('pName', 'VIAF ID'), ('obj', '245922962')]
# [('p', 'http://www.wikidata.org/prop/direct/P7859'), ('pName', 'WorldCat Identities ID'), ('obj', 'lccn-nb2012002495')]
# [('p', 'http://www.wikidata.org/prop/direct/P2397'), ('pName', 'YouTube channel ID'), ('obj', 'UCB_qr75-ydFVKSF9Dmo6izg')]
# [('p', 'http://www.wikidata.org/prop/direct/P1889'), ('pName', 'different from'), ('obj', 'http://www.wikidata.org/entity/Q225109'), ('objName', 'F1')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q68926'), ('objName', '1950 Formula One season')]
# [('p', 'http://www.wikidata.org/prop/direct/P18'), ('pName', 'image'), ('obj', 'http://commons.wikimedia.org/wiki/Special:FilePath/2018%20Austrian%20Grand%20Prix%20turn%201%20%2843147259711%29.jpg')]
# [('p', 'http://www.wikidata.org/prop/direct/P571'), ('pName', 'inception'), ('obj', '1950-01-01T00:00:00Z')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q1344963'), ('objName', 'world championship')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q60147807'), ('objName', 'automobile racing series')]
# [('p', 'http://www.wikidata.org/prop/direct/P2500'), ('pName', 'league level below'), ('obj', 'http://www.wikidata.org/entity/Q687214'), ('objName', 'Formula Two')]
# [('p', 'http://www.wikidata.org/prop/direct/P2500'), ('pName', 'league level below'), ('obj', 'http://www.wikidata.org/entity/Q362400'), ('objName', 'Formule 3000')]
# [('p', 'http://www.wikidata.org/prop/direct/P154'), ('pName', 'logo image'), ('obj', 'http://commons.wikimedia.org/wiki/Special:FilePath/F1.svg')]
# [('p', 'http://www.wikidata.org/prop/direct/P8141'), ('pName', 'motorsportstats.com series ID'), ('obj', 'formula-one')]
# [('p', 'http://www.wikidata.org/prop/direct/P1132'), ('pName', 'number of participants'), ('obj', '20')]
# [('p', 'http://www.wikidata.org/prop/direct/P856'), ('pName', 'official website'), ('obj', 'https://www.formula1.com')]
# [('p', 'http://www.wikidata.org/prop/direct/P137'), ('pName', 'operator'), ('obj', 'http://www.wikidata.org/entity/Q174035'), ('objName', 'Formula One Group')]
# [('p', 'http://www.wikidata.org/prop/direct/P664'), ('pName', 'organizer'), ('obj', 'http://www.wikidata.org/entity/Q179412'), ('objName', "Fédération Internationale de l'Automobile")]
# [('p', 'http://www.wikidata.org/prop/direct/P948'), ('pName', 'page banner'), ('obj', 'http://commons.wikimedia.org/wiki/Special:FilePath/Formula%20One%20page%20banner.jpg')]
# [('p', 'http://www.wikidata.org/prop/direct/P3095'), ('pName', 'practiced by'), ('obj', 'http://www.wikidata.org/entity/Q10841764'), ('objName', 'Formula One driver')]
# [('p', 'http://www.wikidata.org/prop/direct/P8687'), ('pName', 'social media followers'), ('obj', '5148112')]
# [('p', 'http://www.wikidata.org/prop/direct/P8687'), ('pName', 'social media followers'), ('obj', '5720000')]
# [('p', 'http://www.wikidata.org/prop/direct/P641'), ('pName', 'sport'), ('obj', 'http://www.wikidata.org/entity/Q2705092'), ('objName', 'Formula One racing')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('obj', 'http://www.wikidata.org/entity/Q1199515'), ('objName', 'formula racing')]
# [('p', 'http://www.wikidata.org/prop/direct/P3984'), ('pName', 'subreddit'), ('obj', 'formula1')]
# [('p', 'http://www.wikidata.org/prop/direct/P1151'), ('pName', "topic's main Wikimedia portal"), ('obj', 'http://www.wikidata.org/entity/Q6316867'), ('objName', 'Portal:Formula One')]
# [('p', 'http://www.wikidata.org/prop/direct/P910'), ('pName', "topic's main category"), ('obj', 'http://www.wikidata.org/entity/Q7145453'), ('objName', 'Category:Formula One')]
# 64

# %% [markdown]
# Exploring Q2705092 Formula One racing

# %%
queryString = """
SELECT ?p ?pName ?obj ?objName
WHERE { 

wd:Q2705092 ?p ?obj .
        
OPTIONAL {?p <http://schema.org/name> ?pName .}
OPTIONAL{?obj <http://schema.org/name> ?objName .}
} 
ORDER BY ASC (?pName)
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('p', 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), ('obj', 'http://wikiba.se/ontology#Item')]
# [('p', 'http://schema.org/name'), ('obj', 'Formula One racing')]
# [('p', 'http://www.wikidata.org/prop/direct/P1889'), ('pName', 'different from'), ('obj', 'http://www.wikidata.org/entity/Q11924610'), ('objName', 'Formula One Grand Prix')]
# [('p', 'http://www.wikidata.org/prop/direct/P1269'), ('pName', 'facet of'), ('obj', 'http://www.wikidata.org/entity/Q11924610'), ('objName', 'Formula One Grand Prix')]
# [('p', 'http://www.wikidata.org/prop/direct/P3095'), ('pName', 'practiced by'), ('obj', 'http://www.wikidata.org/entity/Q10841764'), ('objName', 'Formula One driver')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('obj', 'http://www.wikidata.org/entity/Q1199515'), ('objName', 'formula racing')]
# 6

# %% [markdown]
# Ho trovato Formula 1 Grand prix Q11924610

# %%
queryString = """
SELECT ?p ?pName ?obj ?objName
WHERE { 

wd:Q11924610 ?p ?obj .
        
OPTIONAL {?p <http://schema.org/name> ?pName .}
OPTIONAL{?obj <http://schema.org/name> ?objName .}
} 
ORDER BY ASC (?pName)
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('p', 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), ('obj', 'http://wikiba.se/ontology#Item')]
# [('p', 'http://schema.org/name'), ('obj', 'Formula One Grand Prix')]
# [('p', 'http://www.wikidata.org/prop/direct/P373'), ('pName', 'Commons category'), ('obj', 'Formula One Grands Prix')]
# [('p', 'http://www.wikidata.org/prop/direct/P1889'), ('pName', 'different from'), ('obj', 'http://www.wikidata.org/entity/Q2705092'), ('objName', 'Formula One racing')]
# [('p', 'http://www.wikidata.org/prop/direct/P2354'), ('pName', 'has list'), ('obj', 'http://www.wikidata.org/entity/Q179371'), ('objName', 'list of Formula One Grands Prix')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q65746180'), ('objName', 'structure of the Formula One Grand Prix')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q65742449'), ('objName', 'Formula One race')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q3055151'), ('objName', 'free practice sessions')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q11944179'), ('objName', 'Formula One qualifying')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('obj', 'http://www.wikidata.org/entity/Q87267404'), ('objName', 'formula race')]
# [('p', 'http://www.wikidata.org/prop/direct/P910'), ('pName', "topic's main category"), ('obj', 'http://www.wikidata.org/entity/Q8468249'), ('objName', 'Category:Formula One Grands Prix')]
# 11

# %% [markdown]
# Questa è la lista dei grand prix...Q179371. Exploring cosidering gran prix as an object

# %%
queryString = """
SELECT ?s ?sName ?p ?pName
WHERE { 

# ?s ?p wd:Q11924610  .
        
OPTIONAL {?s <http://schema.org/name> ?sName .}
OPTIONAL{?p <http://schema.org/name> ?pName .}
} 
ORDER BY ASC (?sName)
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('s', 'http://www.wikidata.org/entity/Q106861620'), ('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of')]
# [('s', 'http://www.wikidata.org/entity/Q20855929'), ('p', 'http://www.wikidata.org/prop/direct/P921'), ('pName', 'main subject')]
# [('s', 'http://www.wikidata.org/entity/Q21826783'), ('p', 'http://www.w3.org/2002/07/owl#sameAs')]
# [('s', 'http://www.wikidata.org/entity/Q12766446'), ('p', 'http://www.w3.org/2002/07/owl#sameAs')]
# [('s', 'http://www.wikidata.org/entity/Q12390157'), ('p', 'http://www.w3.org/2002/07/owl#sameAs')]
# [('s', 'https://www.wikidata.org/wiki/Special:EntityData/Q11924610'), ('p', 'http://schema.org/about')]
# [('s', 'http://www.wikidata.org/entity/Q67123903'), ('sName', '2020 Australian Grand Prix'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q67123905'), ('sName', '2020 Bahrain Grand Prix'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q67123906'), ('sName', '2020 Vietnamese Grand Prix'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q96088886'), ('sName', '70th Anniversary Grand Prix'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q7849'), ('sName', 'Abu Dhabi Grand Prix'), ('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of')]
# [('s', 'http://www.wikidata.org/entity/Q7854'), ('sName', 'Argentine Grand Prix'), ('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of')]
# [('s', 'http://www.wikidata.org/entity/Q7870'), ('sName', 'Australian Grand Prix'), ('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of')]
# [('s', 'http://www.wikidata.org/entity/Q7876'), ('sName', 'Austrian Grand Prix'), ('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of')]
# [('s', 'http://www.wikidata.org/entity/Q27940843'), ('sName', 'Azerbaijan Grand Prix'), ('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of')]
# [('s', 'http://www.wikidata.org/entity/Q7885'), ('sName', 'Bahrain Grand Prix'), ('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of')]
# [('s', 'http://www.wikidata.org/entity/Q7954'), ('sName', 'Belgian Grand Prix'), ('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of')]
# [('s', 'http://www.wikidata.org/entity/Q7961'), ('sName', 'Brazilian Grand Prix'), ('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of')]
# [('s', 'http://www.wikidata.org/entity/Q8019'), ('sName', 'British Grand Prix'), ('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of')]
# [('s', 'http://www.wikidata.org/entity/Q8039'), ('sName', 'Caesars Palace Grand Prix'), ('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of')]
# [('s', 'http://www.wikidata.org/entity/Q7965'), ('sName', 'Canadian Grand Prix'), ('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of')]
# [('s', 'http://www.wikidata.org/entity/Q8468249'), ('sName', 'Category:Formula One Grands Prix'), ('p', 'http://www.wikidata.org/prop/direct/P301'), ('pName', "category's main topic")]
# [('s', 'http://www.wikidata.org/entity/Q7980'), ('sName', 'Chinese Grand Prix'), ('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of')]
# [('s', 'http://www.wikidata.org/entity/Q1131293'), ('sName', 'Coppa Acerbo'), ('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of')]
# [('s', 'http://www.wikidata.org/entity/Q2338574'), ('sName', 'Dallas Grand Prix'), ('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of')]
# [('s', 'http://www.wikidata.org/entity/Q9214'), ('sName', 'Detroit Grand Prix'), ('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of')]
# [('s', 'http://www.wikidata.org/entity/Q9109'), ('sName', 'Dutch Grand Prix'), ('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of')]
# [('s', 'http://www.wikidata.org/entity/Q100953125'), ('sName', 'Emilia Romagna Grand Prix'), ('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of')]
# [('s', 'http://www.wikidata.org/entity/Q7994'), ('sName', 'European Grand Prix'), ('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of')]
# [('s', 'http://www.wikidata.org/entity/Q11944179'), ('sName', 'Formula One qualifying'), ('p', 'http://www.wikidata.org/prop/direct/P361'), ('pName', 'part of')]
# [('s', 'http://www.wikidata.org/entity/Q65742449'), ('sName', 'Formula One race'), ('p', 'http://www.wikidata.org/prop/direct/P361'), ('pName', 'part of')]
# [('s', 'http://www.wikidata.org/entity/Q2705092'), ('sName', 'Formula One racing'), ('p', 'http://www.wikidata.org/prop/direct/P1269'), ('pName', 'facet of')]
# [('s', 'http://www.wikidata.org/entity/Q2705092'), ('sName', 'Formula One racing'), ('p', 'http://www.wikidata.org/prop/direct/P1889'), ('pName', 'different from')]
# [('s', 'http://www.wikidata.org/entity/Q7997'), ('sName', 'French Grand Prix'), ('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of')]
# [('s', 'http://www.wikidata.org/entity/Q7998'), ('sName', 'German Grand Prix'), ('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of')]
# [('s', 'http://www.wikidata.org/entity/Q170096'), ('sName', 'Grand Prix of America'), ('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of')]
# [('s', 'http://www.wikidata.org/entity/Q9233'), ('sName', 'Hungarian Grand Prix'), ('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of')]
# [('s', 'http://www.wikidata.org/entity/Q8025'), ('sName', 'Indian Grand Prix'), ('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of')]
# [('s', 'http://www.wikidata.org/entity/Q8032'), ('sName', 'Indianapolis 500'), ('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of')]
# [('s', 'http://www.wikidata.org/entity/Q8036'), ('sName', 'Italian Grand Prix'), ('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of')]
# [('s', 'http://www.wikidata.org/entity/Q8000'), ('sName', 'Japanese Grand Prix'), ('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of')]
# [('s', 'http://www.wikidata.org/entity/Q105682965'), ('sName', "Johnny Herbert's Grand Prix Championship 1998"), ('p', 'http://www.wikidata.org/prop/direct/P921'), ('pName', 'main subject')]
# [('s', 'http://www.wikidata.org/entity/Q7993'), ('sName', 'Korean Grand Prix'), ('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of')]
# [('s', 'http://www.wikidata.org/entity/Q8069'), ('sName', 'Luxembourg Grand Prix'), ('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of')]
# [('s', 'http://www.wikidata.org/entity/Q8082'), ('sName', 'Malaysian Grand Prix'), ('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of')]
# [('s', 'http://www.wikidata.org/entity/Q8109'), ('sName', 'Mexican Grand Prix'), ('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of')]
# [('s', 'http://www.wikidata.org/entity/Q106856346'), ('sName', 'Mexico City Grand Prix'), ('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of')]
# [('s', 'http://www.wikidata.org/entity/Q106545547'), ('sName', 'Miami Grand Prix'), ('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of')]
# [('s', 'http://www.wikidata.org/entity/Q9102'), ('sName', 'Monaco Grand Prix'), ('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of')]
# [('s', 'http://www.wikidata.org/entity/Q8100'), ('sName', 'Moroccan Grand Prix'), ('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of')]
# [('s', 'http://www.wikidata.org/entity/Q9113'), ('sName', 'Pacific Grand Prix'), ('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of')]
# [('s', 'http://www.wikidata.org/entity/Q9117'), ('sName', 'Portuguese Grand Prix'), ('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of')]
# [('s', 'http://www.wikidata.org/entity/Q173271'), ('sName', 'Russian Grand Prix'), ('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of')]
# [('s', 'http://www.wikidata.org/entity/Q98637324'), ('sName', 'Sakhir Grand Prix'), ('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of')]
# [('s', 'http://www.wikidata.org/entity/Q9122'), ('sName', 'San Marino Grand Prix'), ('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of')]
# [('s', 'http://www.wikidata.org/entity/Q101206065'), ('sName', 'Saudi Arabian Grand Prix'), ('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of')]
# [('s', 'http://www.wikidata.org/entity/Q9137'), ('sName', 'Singapore Grand Prix'), ('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of')]
# [('s', 'http://www.wikidata.org/entity/Q9227'), ('sName', 'South African Grand Prix'), ('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of')]
# [('s', 'http://www.wikidata.org/entity/Q9208'), ('sName', 'Spanish Grand Prix'), ('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of')]
# [('s', 'http://www.wikidata.org/entity/Q96482998'), ('sName', 'Styrian Grand Prix'), ('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of')]
# [('s', 'http://www.wikidata.org/entity/Q9223'), ('sName', 'Swedish Grand Prix'), ('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of')]
# [('s', 'http://www.wikidata.org/entity/Q9225'), ('sName', 'Swiss Grand Prix'), ('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of')]
# [('s', 'http://www.wikidata.org/entity/Q104216769'), ('sName', 'São Paulo Grand Prix'), ('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of')]
# [('s', 'http://www.wikidata.org/entity/Q9229'), ('sName', 'Turkish Grand Prix'), ('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of')]
# [('s', 'http://www.wikidata.org/entity/Q9220'), ('sName', 'United States Grand Prix West'), ('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of')]
# [('s', 'http://www.wikidata.org/entity/Q9209'), ('sName', 'United States Grand Prix'), ('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of')]
# [('s', 'http://www.wikidata.org/entity/Q58336227'), ('sName', 'Vietnamese Grand Prix'), ('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of')]
# [('s', 'http://www.wikidata.org/entity/Q3055151'), ('sName', 'free practice sessions'), ('p', 'http://www.wikidata.org/prop/direct/P361'), ('pName', 'part of')]
# [('s', 'http://www.wikidata.org/entity/Q179371'), ('sName', 'list of Formula One Grands Prix'), ('p', 'http://www.wikidata.org/prop/direct/P360'), ('pName', 'is a list of')]
# [('s', 'http://www.wikidata.org/entity/Q65746180'), ('sName', 'structure of the Formula One Grand Prix'), ('p', 'http://www.wikidata.org/prop/direct/P361'), ('pName', 'part of')]
# 70

# %% [markdown]
# Q7849 looking for the edition of that event.

# %%
queryString = """
SELECT ?p ?pName ?obj ?objName
WHERE { 

wd:Q7849 ?p ?obj  .
        
OPTIONAL {?obj <http://schema.org/name> ?objName .}
OPTIONAL{?p <http://schema.org/name> ?pName .}
} 
ORDER BY ASC (?pName)
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('p', 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), ('obj', 'http://wikiba.se/ontology#Item')]
# [('p', 'http://www.wikidata.org/prop/direct-normalized/P646'), ('obj', 'http://g.co/kg/m/02q3d9b')]
# [('p', 'http://schema.org/name'), ('obj', 'Abu Dhabi Grand Prix')]
# [('p', 'http://www.wikidata.org/prop/direct/P373'), ('pName', 'Commons category'), ('obj', 'Abu Dhabi Grand Prix')]
# [('p', 'http://www.wikidata.org/prop/direct/P646'), ('pName', 'Freebase ID'), ('obj', '/m/02q3d9b')]
# [('p', 'http://www.wikidata.org/prop/direct/P5247'), ('pName', 'Giant Bomb ID'), ('obj', '3015-4894')]
# [('p', 'http://www.wikidata.org/prop/direct/P17'), ('pName', 'country'), ('obj', 'http://www.wikidata.org/entity/Q878'), ('objName', 'United Arab Emirates')]
# [('p', 'http://www.wikidata.org/prop/direct/P2257'), ('pName', 'event interval'), ('obj', '1')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q19601896'), ('objName', '2015 Abu Dhabi Grand Prix')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q11912'), ('objName', '2009 Abu Dhabi Grand Prix')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q48311418'), ('objName', '2018 Abu Dhabi Grand Prix')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q11879164'), ('objName', '2013 Abu Dhabi Grand Prix')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q11916'), ('objName', '2012 Abu Dhabi Grand Prix')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q11914'), ('objName', '2010 Abu Dhabi Grand Prix')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q11915'), ('objName', '2011 Abu Dhabi Grand Prix')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q29068728'), ('objName', '2017 Abu Dhabi Grand Prix')]
# [('p', 'http://www.wikidata.org/prop/direct/P18'), ('pName', 'image'), ('obj', 'http://commons.wikimedia.org/wiki/Special:FilePath/Circuit%20Yas-Island.svg')]
# [('p', 'http://www.wikidata.org/prop/direct/P571'), ('pName', 'inception'), ('obj', '2009-01-01T00:00:00Z')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q18608583'), ('objName', 'recurring sporting event')]
# [('p', 'http://www.wikidata.org/prop/direct/P276'), ('pName', 'location'), ('obj', 'http://www.wikidata.org/entity/Q172869'), ('objName', 'Yas Marina Circuit')]
# [('p', 'http://www.wikidata.org/prop/direct/P856'), ('pName', 'official website'), ('obj', 'https://abudhabigp.com')]
# [('p', 'http://www.wikidata.org/prop/direct/P664'), ('pName', 'organizer'), ('obj', 'http://www.wikidata.org/entity/Q179412'), ('objName', "Fédération Internationale de l'Automobile")]
# [('p', 'http://www.wikidata.org/prop/direct/P641'), ('pName', 'sport'), ('obj', 'http://www.wikidata.org/entity/Q5386'), ('objName', 'auto racing')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('obj', 'http://www.wikidata.org/entity/Q11924610'), ('objName', 'Formula One Grand Prix')]
# [('p', 'http://www.wikidata.org/prop/direct/P910'), ('pName', "topic's main category"), ('obj', 'http://www.wikidata.org/entity/Q8168565'), ('objName', 'Category:Abu Dhabi Grand Prix')]
# [('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner'), ('obj', 'http://www.wikidata.org/entity/Q2239218'), ('objName', 'Max Verstappen')]
# 26

# %% [markdown]
# "Has part": Times a Grand Prix was held.
#
# Monza Q8036 ?

# %%
queryString = """
SELECT ?p ?pName ?obj ?objName
WHERE { 

wd:Q8036 ?p ?obj  .
        
OPTIONAL {?obj <http://schema.org/name> ?objName .}
OPTIONAL{?p <http://schema.org/name> ?pName .}
} 
ORDER BY ASC (?pName)
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('p', 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), ('obj', 'http://wikiba.se/ontology#Item')]
# [('p', 'http://www.wikidata.org/prop/direct-normalized/P214'), ('obj', 'http://viaf.org/viaf/315594845')]
# [('p', 'http://www.wikidata.org/prop/direct-normalized/P244'), ('obj', 'https://id.loc.gov/authorities/names/n2015027156')]
# [('p', 'http://www.wikidata.org/prop/direct-normalized/P646'), ('obj', 'http://g.co/kg/m/02k2fp')]
# [('p', 'http://schema.org/name'), ('obj', 'Italian Grand Prix')]
# [('p', 'http://www.wikidata.org/prop/direct/P373'), ('pName', 'Commons category'), ('obj', 'Italian Grand Prix')]
# [('p', 'http://www.wikidata.org/prop/direct/P646'), ('pName', 'Freebase ID'), ('obj', '/m/02k2fp')]
# [('p', 'http://www.wikidata.org/prop/direct/P244'), ('pName', 'Library of Congress authority ID'), ('obj', 'n2015027156')]
# [('p', 'http://www.wikidata.org/prop/direct/P3417'), ('pName', 'Quora topic ID'), ('obj', 'Italian-Grand-Prix')]
# [('p', 'http://www.wikidata.org/prop/direct/P214'), ('pName', 'VIAF ID'), ('obj', '315594845')]
# [('p', 'http://www.wikidata.org/prop/direct/P17'), ('pName', 'country'), ('obj', 'http://www.wikidata.org/entity/Q38'), ('objName', 'Italy')]
# [('p', 'http://www.wikidata.org/prop/direct/P1889'), ('pName', 'different from'), ('obj', 'http://www.wikidata.org/entity/Q7575673'), ('objName', 'Speedway Grand Prix of Italy')]
# [('p', 'http://www.wikidata.org/prop/direct/P2257'), ('pName', 'event interval'), ('obj', '1')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q252217'), ('objName', '1957 Italian Grand Prix')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q362773'), ('objName', '1991 Italian Grand Prix')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q362802'), ('objName', '1992 Italian Grand Prix')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q362937'), ('objName', '1997 Italian Grand Prix')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q363191'), ('objName', '2002 Italian Grand Prix')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q363270'), ('objName', '2003 Italian Grand Prix')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q363328'), ('objName', '2005 Italian Grand Prix')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q280344'), ('objName', '1947 Italian Grand Prix')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q331248'), ('objName', '1958 Italian Grand Prix')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q171750'), ('objName', '1972 Italian Grand Prix')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q221835'), ('objName', '2011 Italian Grand Prix')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q106317431'), ('objName', '2021 Italian Grand Prix')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q23045185'), ('objName', '2016 Italian Grand Prix')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q363365'), ('objName', '2007 Italian Grand Prix')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q2021974'), ('objName', '1925 Italian Grand Prix')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q171657'), ('objName', '1988 Italian Grand Prix')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q173021'), ('objName', '1951 Italian Grand Prix')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q173753'), ('objName', '1923 Italian Grand Prix')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q3113820'), ('objName', '1928 Italian Grand Prix')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q173101'), ('objName', '2012 Italian Grand Prix')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q48311295'), ('objName', '2018 Italian Grand Prix')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q3113822'), ('objName', '1935 Italian Grand Prix')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q331305'), ('objName', '1960 Italian Grand Prix')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q331344'), ('objName', '1962 Italian Grand Prix')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q3774489'), ('objName', '1932 Italian Grand Prix')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q173025'), ('objName', '1950 Italian Grand Prix')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q6352437'), ('objName', '2013 Italian Grand Prix')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q171880'), ('objName', '1980 Italian Grand Prix')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q172088'), ('objName', '1971 Italian Grand Prix')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q362653'), ('objName', '1985 Italian Grand Prix')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q362821'), ('objName', '1993 Italian Grand Prix')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q363315'), ('objName', '2004 Italian Grand Prix')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q2021956'), ('objName', '1931 Italian Grand Prix')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q3113826'), ('objName', '1937 Italian Grand Prix')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q1654235'), ('objName', '1948 Italian Grand Prix')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q171679'), ('objName', '1979 Italian Grand Prix')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q171681'), ('objName', '1978 Italian Grand Prix')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q171715'), ('objName', '1976 Italian Grand Prix')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q171763'), ('objName', '1967 Italian Grand Prix')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q171802'), ('objName', '1975 Italian Grand Prix')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q171855'), ('objName', '1970 Italian Grand Prix')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q171858'), ('objName', '1981 Italian Grand Prix')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q171870'), ('objName', '1969 Italian Grand Prix')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q171887'), ('objName', '1977 Italian Grand Prix')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q171919'), ('objName', '1974 Italian Grand Prix')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q171938'), ('objName', '1961 Italian Grand Prix')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q171939'), ('objName', '1963 Italian Grand Prix')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q171940'), ('objName', '1955 Italian Grand Prix')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q17195693'), ('objName', '2014 Italian Grand Prix')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q172028'), ('objName', '1968 Italian Grand Prix')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q172166'), ('objName', '1973 Italian Grand Prix')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q172942'), ('objName', '2010 Italian Grand Prix')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q173023'), ('objName', '1952 Italian Grand Prix')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q173036'), ('objName', '1953 Italian Grand Prix')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q173193'), ('objName', '2009 Italian Grand Prix')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q173344'), ('objName', '1966 Italian Grand Prix')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q173748'), ('objName', '1922 Italian Grand Prix')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q173750'), ('objName', '1921 Italian Grand Prix')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q179397'), ('objName', '2008 Italian Grand Prixa')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q19936556'), ('objName', '2015 Italian Grand Prix')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q221240'), ('objName', '1990 Italian Grand Prix')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q221461'), ('objName', '2006 Italian Grand Prix')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q260127'), ('objName', '1989 Italian Grand Prix')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q29062712'), ('objName', '2017 Italian Grand Prix')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q3113815'), ('objName', '1924 Italian Grand Prix')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q3113817'), ('objName', '1926 Italian Grand Prix')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q3113818'), ('objName', '1933 Italian Grand Prix')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q3113821'), ('objName', '1934 Italian Grand Prix')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q3113823'), ('objName', '1927 Italian Grand Prix')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q3113825'), ('objName', '1936 Italian Grand Prix')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q3113827'), ('objName', '1938 Italian Grand Prix')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q331178'), ('objName', '1954 Italian Grand Prix')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q331218'), ('objName', '1956 Italian Grand Prix')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q331272'), ('objName', '1959 Italian Grand Prix')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q332662'), ('objName', '1964 Italian Grand Prix')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q362300'), ('objName', '1965 Italian Grand Prix')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q362574'), ('objName', '1982 Italian Grand Prix')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q362598'), ('objName', '1983 Italian Grand Prix')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q362628'), ('objName', '1984 Italian Grand Prix')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q362676'), ('objName', '1986 Italian Grand Prix')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q362715'), ('objName', '1987 Italian Grand Prix')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q362855'), ('objName', '1994 Italian Grand Prix')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q362881'), ('objName', '1995 Italian Grand Prix')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q362914'), ('objName', '1996 Italian Grand Prix')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q362961'), ('objName', '1998 Italian Grand Prix')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q362986'), ('objName', '1999 Italian Grand Prix')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q363051'), ('objName', '2000 Italian Grand Prix')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q363136'), ('objName', '2001 Italian Grand Prix')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q3774488'), ('objName', '1949 Italian Grand Prix')]
# [('p', 'http://www.wikidata.org/prop/direct/P18'), ('pName', 'image'), ('obj', 'http://commons.wikimedia.org/wiki/Special:FilePath/Monza%20track%20map.svg')]
# [('p', 'http://www.wikidata.org/prop/direct/P571'), ('pName', 'inception'), ('obj', '1921-01-01T00:00:00Z')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q18608583'), ('objName', 'recurring sporting event')]
# [('p', 'http://www.wikidata.org/prop/direct/P276'), ('pName', 'location'), ('obj', 'http://www.wikidata.org/entity/Q171417'), ('objName', 'Autodromo Nazionale Monza')]
# [('p', 'http://www.wikidata.org/prop/direct/P856'), ('pName', 'official website'), ('obj', 'https://www.monzanet.it/interno.php?id=49')]
# [('p', 'http://www.wikidata.org/prop/direct/P664'), ('pName', 'organizer'), ('obj', 'http://www.wikidata.org/entity/Q179412'), ('objName', "Fédération Internationale de l'Automobile")]
# [('p', 'http://www.wikidata.org/prop/direct/P641'), ('pName', 'sport'), ('obj', 'http://www.wikidata.org/entity/Q5367'), ('objName', 'motorsport')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('obj', 'http://www.wikidata.org/entity/Q11924610'), ('objName', 'Formula One Grand Prix')]
# [('p', 'http://www.wikidata.org/prop/direct/P910'), ('pName', "topic's main category"), ('obj', 'http://www.wikidata.org/entity/Q8136047'), ('objName', 'Category:Italian Grand Prix')]
# [('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner'), ('obj', 'http://www.wikidata.org/entity/Q11816647'), ('objName', 'Pierre Gasly')]
# 112

# %% [markdown]
# Yes, "has part" it is the number of times a circut was used by F1.
#
# NowI can search for the list of driver present in an edition. 2012 "Q173101"

# %%
queryString = """
SELECT ?p ?pName ?obj ?objName
WHERE { 

wd:Q173101 ?p ?obj  .
        
OPTIONAL {?obj <http://schema.org/name> ?objName .}
OPTIONAL{?p <http://schema.org/name> ?pName .}
} 
ORDER BY ASC (?pName)
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('p', 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), ('obj', 'http://wikiba.se/ontology#Item')]
# [('p', 'http://www.wikidata.org/prop/direct-normalized/P646'), ('obj', 'http://g.co/kg/m/0ll0x90')]
# [('p', 'http://schema.org/name'), ('obj', '2012 Italian Grand Prix')]
# [('p', 'http://www.wikidata.org/prop/direct/P373'), ('pName', 'Commons category'), ('obj', '2012 Italian Grand Prix')]
# [('p', 'http://www.wikidata.org/prop/direct/P646'), ('pName', 'Freebase ID'), ('obj', '/m/0ll0x90')]
# [('p', 'http://www.wikidata.org/prop/direct/P17'), ('pName', 'country'), ('obj', 'http://www.wikidata.org/entity/Q38'), ('objName', 'Italy')]
# [('p', 'http://www.wikidata.org/prop/direct/P3157'), ('pName', 'event distance'), ('obj', '53')]
# [('p', 'http://www.wikidata.org/prop/direct/P5053'), ('pName', 'fastest lap'), ('obj', 'http://www.wikidata.org/entity/Q75820'), ('objName', 'Nico Rosberg')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q8036'), ('objName', 'Italian Grand Prix')]
# [('p', 'http://www.wikidata.org/prop/direct/P276'), ('pName', 'location'), ('obj', 'http://www.wikidata.org/entity/Q171417'), ('objName', 'Autodromo Nazionale Monza')]
# [('p', 'http://www.wikidata.org/prop/direct/P361'), ('pName', 'part of'), ('obj', 'http://www.wikidata.org/entity/Q69959'), ('objName', '2012 Formula One World Championship')]
# [('p', 'http://www.wikidata.org/prop/direct/P585'), ('pName', 'point in time'), ('obj', '2012-09-09T00:00:00Z')]
# [('p', 'http://www.wikidata.org/prop/direct/P3764'), ('pName', 'pole position'), ('obj', 'http://www.wikidata.org/entity/Q9673'), ('objName', 'Lewis Hamilton')]
# [('p', 'http://www.wikidata.org/prop/direct/P6806'), ('pName', 'racing-reference race ID'), ('obj', '2012_Santander_Grand_Prix_of_Italy/F')]
# [('p', 'http://www.wikidata.org/prop/direct/P641'), ('pName', 'sport'), ('obj', 'http://www.wikidata.org/entity/Q5386'), ('objName', 'auto racing')]
# [('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner'), ('obj', 'http://www.wikidata.org/entity/Q9673'), ('objName', 'Lewis Hamilton')]
# 16

# %% [markdown]
# Provo al contrario

# %%
queryString = """
SELECT ?s ?sName ?p ?pName
WHERE { 

# ?s ?p wd:Q173101 .
        
OPTIONAL {?s <http://schema.org/name> ?sName .}
OPTIONAL{?p <http://schema.org/name> ?pName .}
} 
ORDER BY ASC (?sName)
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('s', 'https://www.wikidata.org/wiki/Special:EntityData/Q173101'), ('p', 'http://schema.org/about')]
# [('s', 'http://www.wikidata.org/entity/Q69959'), ('sName', '2012 Formula One World Championship'), ('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part')]
# [('s', 'http://www.wikidata.org/entity/Q8036'), ('sName', 'Italian Grand Prix'), ('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part')]
# 3

# %% [markdown]
# Monza as an object

# %%
queryString = """
SELECT ?s ?sName ?p ?pName
WHERE { 

# ?s ?p wd:Q8036  .
        
OPTIONAL {?s <http://schema.org/name> ?sName .}
OPTIONAL{?p <http://schema.org/name> ?pName .}
} 
ORDER BY ASC (?sName)
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('s', 'http://www.wikidata.org/entity/Q56409636'), ('p', 'http://www.w3.org/2002/07/owl#sameAs')]
# [('s', 'http://www.wikidata.org/entity/Q6104909'), ('p', 'http://www.w3.org/2002/07/owl#sameAs')]
# [('s', 'https://www.wikidata.org/wiki/Special:EntityData/Q8036'), ('p', 'http://schema.org/about')]
# [('s', 'http://www.wikidata.org/entity/Q173750'), ('sName', '1921 Italian Grand Prix'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q173748'), ('sName', '1922 Italian Grand Prix'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q173753'), ('sName', '1923 Italian Grand Prix'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q3113815'), ('sName', '1924 Italian Grand Prix'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q2021974'), ('sName', '1925 Italian Grand Prix'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q3113817'), ('sName', '1926 Italian Grand Prix'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q3113823'), ('sName', '1927 Italian Grand Prix'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q3113820'), ('sName', '1928 Italian Grand Prix'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q2021956'), ('sName', '1931 Italian Grand Prix'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q3774489'), ('sName', '1932 Italian Grand Prix'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q3113818'), ('sName', '1933 Italian Grand Prix'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q3113821'), ('sName', '1934 Italian Grand Prix'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q3113822'), ('sName', '1935 Italian Grand Prix'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q3113825'), ('sName', '1936 Italian Grand Prix'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q3113826'), ('sName', '1937 Italian Grand Prix'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q3113827'), ('sName', '1938 Italian Grand Prix'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q280344'), ('sName', '1947 Italian Grand Prix'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q1654235'), ('sName', '1948 Italian Grand Prix'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q3774488'), ('sName', '1949 Italian Grand Prix'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q173025'), ('sName', '1950 Italian Grand Prix'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q173021'), ('sName', '1951 Italian Grand Prix'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q173023'), ('sName', '1952 Italian Grand Prix'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q173036'), ('sName', '1953 Italian Grand Prix'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q331178'), ('sName', '1954 Italian Grand Prix'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q171940'), ('sName', '1955 Italian Grand Prix'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q331218'), ('sName', '1956 Italian Grand Prix'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q252217'), ('sName', '1957 Italian Grand Prix'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q331248'), ('sName', '1958 Italian Grand Prix'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q331272'), ('sName', '1959 Italian Grand Prix'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q331305'), ('sName', '1960 Italian Grand Prix'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q171938'), ('sName', '1961 Italian Grand Prix'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q331344'), ('sName', '1962 Italian Grand Prix'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q171939'), ('sName', '1963 Italian Grand Prix'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q332662'), ('sName', '1964 Italian Grand Prix'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q362300'), ('sName', '1965 Italian Grand Prix'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q173344'), ('sName', '1966 Italian Grand Prix'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q171763'), ('sName', '1967 Italian Grand Prix'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q172028'), ('sName', '1968 Italian Grand Prix'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q171870'), ('sName', '1969 Italian Grand Prix'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q171855'), ('sName', '1970 Italian Grand Prix'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q172088'), ('sName', '1971 Italian Grand Prix'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q171750'), ('sName', '1972 Italian Grand Prix'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q172166'), ('sName', '1973 Italian Grand Prix'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q171919'), ('sName', '1974 Italian Grand Prix'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q171802'), ('sName', '1975 Italian Grand Prix'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q171715'), ('sName', '1976 Italian Grand Prix'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q171887'), ('sName', '1977 Italian Grand Prix'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q171681'), ('sName', '1978 Italian Grand Prix'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q171679'), ('sName', '1979 Italian Grand Prix'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q171880'), ('sName', '1980 Italian Grand Prix'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q171858'), ('sName', '1981 Italian Grand Prix'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q362574'), ('sName', '1982 Italian Grand Prix'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q362598'), ('sName', '1983 Italian Grand Prix'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q362628'), ('sName', '1984 Italian Grand Prix'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q362653'), ('sName', '1985 Italian Grand Prix'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q362676'), ('sName', '1986 Italian Grand Prix'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q362715'), ('sName', '1987 Italian Grand Prix'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q171657'), ('sName', '1988 Italian Grand Prix'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q260127'), ('sName', '1989 Italian Grand Prix'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q221240'), ('sName', '1990 Italian Grand Prix'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q362773'), ('sName', '1991 Italian Grand Prix'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q362802'), ('sName', '1992 Italian Grand Prix'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q362821'), ('sName', '1993 Italian Grand Prix'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q362855'), ('sName', '1994 Italian Grand Prix'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q362881'), ('sName', '1995 Italian Grand Prix'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q362914'), ('sName', '1996 Italian Grand Prix'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q362937'), ('sName', '1997 Italian Grand Prix'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q362961'), ('sName', '1998 Italian Grand Prix'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q362986'), ('sName', '1999 Italian Grand Prix'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q363051'), ('sName', '2000 Italian Grand Prix'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q363136'), ('sName', '2001 Italian Grand Prix'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q363191'), ('sName', '2002 Italian Grand Prix'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q363270'), ('sName', '2003 Italian Grand Prix'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q363315'), ('sName', '2004 Italian Grand Prix'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q363328'), ('sName', '2005 Italian Grand Prix'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q221461'), ('sName', '2006 Italian Grand Prix'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q363365'), ('sName', '2007 Italian Grand Prix'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q179397'), ('sName', '2008 Italian Grand Prixa'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q173193'), ('sName', '2009 Italian Grand Prix'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q172942'), ('sName', '2010 Italian Grand Prix'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q221835'), ('sName', '2011 Italian Grand Prix'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q173101'), ('sName', '2012 Italian Grand Prix'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q6352437'), ('sName', '2013 Italian Grand Prix'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q17195693'), ('sName', '2014 Italian Grand Prix'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q19936556'), ('sName', '2015 Italian Grand Prix'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q23045185'), ('sName', '2016 Italian Grand Prix'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q29062712'), ('sName', '2017 Italian Grand Prix'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q48311295'), ('sName', '2018 Italian Grand Prix'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q61366427'), ('sName', '2019 Italian Grand Prix'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q67123918'), ('sName', '2020 Italian Grand Prix'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q106317431'), ('sName', '2021 Italian Grand Prix'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q8136047'), ('sName', 'Category:Italian Grand Prix'), ('p', 'http://www.wikidata.org/prop/direct/P301'), ('pName', "category's main topic")]
# 95

# %% [markdown]
# "formula one race" entity Q65742449

# %%
queryString = """
SELECT ?s ?sName ?p ?pName
WHERE { 

# ?s ?p wd:Q65742449  .
        
OPTIONAL {?s <http://schema.org/name> ?sName .}
OPTIONAL{?p <http://schema.org/name> ?pName .}
} 
ORDER BY ASC (?sName)
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('s', 'https://www.wikidata.org/wiki/Special:EntityData/Q65742449'), ('p', 'http://schema.org/about')]
# [('s', 'http://www.wikidata.org/entity/Q49000192'), ('sName', '1951 Bordeaux Grand Prix'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q49000184'), ('sName', '1951 Richmond Trophy'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q7902163'), ('sName', 'Category:1973 Formula One races'), ('p', 'http://www.wikidata.org/prop/direct/P4224'), ('pName', 'category contains')]
# [('s', 'http://www.wikidata.org/entity/Q105801254'), ('sName', 'Category:2021 Formula One races'), ('p', 'http://www.wikidata.org/prop/direct/P971'), ('pName', 'category combines topics')]
# [('s', 'http://www.wikidata.org/entity/Q100251706'), ('sName', 'Eifel Grand Prix'), ('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of')]
# [('s', 'http://www.wikidata.org/entity/Q11924610'), ('sName', 'Formula One Grand Prix'), ('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part')]
# [('s', 'http://www.wikidata.org/entity/Q9114'), ('sName', 'Pescara Grand Prix'), ('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of')]
# [('s', 'http://www.wikidata.org/entity/Q912234'), ('sName', 'Race of Two Worlds'), ('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of')]
# [('s', 'http://www.wikidata.org/entity/Q2341353'), ('sName', 'San Remo Grand Prix'), ('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of')]
# [('s', 'http://www.wikidata.org/entity/Q97120595'), ('sName', 'Tuscan Grand Prix'), ('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of')]
# 11

# %%
queryString = """
SELECT ?p ?pName ?obj ?objName
WHERE { 

wd:Q65742449 ?p ?obj   .
        
OPTIONAL {?obj <http://schema.org/name> ?objName .}
OPTIONAL{?p <http://schema.org/name> ?pName .}
} 
ORDER BY ASC (?sName)
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P641'), ('pName', 'sport'), ('obj', 'http://www.wikidata.org/entity/Q2705092'), ('objName', 'Formula One racing')]
# [('p', 'http://www.wikidata.org/prop/direct/P361'), ('pName', 'part of'), ('obj', 'http://www.wikidata.org/entity/Q11924610'), ('objName', 'Formula One Grand Prix')]
# [('p', 'http://www.wikidata.org/prop/direct/P641'), ('pName', 'sport'), ('obj', 'http://www.wikidata.org/entity/Q5386'), ('objName', 'auto racing')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('obj', 'http://www.wikidata.org/entity/Q87267404'), ('objName', 'formula race')]
# [('p', 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), ('obj', 'http://wikiba.se/ontology#Item')]
# [('p', 'http://schema.org/name'), ('obj', 'Formula One race')]
# 6

# %% [markdown]
# PUNTO 1 SDA COPLETARE---- NON TROVO RISPOSTA. PASSO AL 2, DOVE HO GIà MOLTE PIù INFORMAZIONI
#
# -----------------------------

# %% [markdown]
# **Identify the BGP that connects a F1 team to a parent company**

# %% [markdown]
# Looking at Vettel teams I can see many possibilities. Starting from the recent one: AMR<br>
# Q173663 Red Bull Racing <br>
# Q750016 Aston Martin Racing <br>
# Q141818 Scuderia Toro Rosso <br>
# Q154118 BMW Sauber <br>
# Q169898 Scuderia Ferrari <br>

# %%
queryString = """
SELECT ?p ?pName ?obj ?objName
WHERE { 

wd:Q750016 ?p ?obj   .
        
OPTIONAL {?obj <http://schema.org/name> ?objName .}
OPTIONAL{?p <http://schema.org/name> ?pName .}
} 
ORDER BY ASC (?pName)
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('p', 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), ('obj', 'http://wikiba.se/ontology#Item')]
# [('p', 'http://www.wikidata.org/prop/direct-normalized/P646'), ('obj', 'http://g.co/kg/m/047v0hq')]
# [('p', 'http://schema.org/name'), ('obj', 'Aston Martin Racing')]
# [('p', 'http://www.wikidata.org/prop/direct/P373'), ('pName', 'Commons category'), ('obj', 'Aston Martin Racing')]
# [('p', 'http://www.wikidata.org/prop/direct/P646'), ('pName', 'Freebase ID'), ('obj', '/m/047v0hq')]
# [('p', 'http://www.wikidata.org/prop/direct/P17'), ('pName', 'country'), ('obj', 'http://www.wikidata.org/entity/Q145'), ('objName', 'United Kingdom')]
# [('p', 'http://www.wikidata.org/prop/direct/P18'), ('pName', 'image'), ('obj', 'http://commons.wikimedia.org/wiki/Special:FilePath/Aston%20Martin%20Vantage%20GTE%20Lynn%20Silverstone%202018.jpg')]
# [('p', 'http://www.wikidata.org/prop/direct/P571'), ('pName', 'inception'), ('obj', '2004-01-01T00:00:00Z')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q20074337'), ('objName', 'auto racing team')]
# [('p', 'http://www.wikidata.org/prop/direct/P856'), ('pName', 'official website'), ('obj', 'http://www.astonmartinracing.com/')]
# [('p', 'http://www.wikidata.org/prop/direct/P361'), ('pName', 'part of'), ('obj', 'http://www.wikidata.org/entity/Q27074'), ('objName', 'Aston Martin Lagonda')]
# 11

# %% [markdown]
# Using P361 "part of".
#
# I consider the reverse path

# %%
queryString = """
SELECT ?s ?sName ?p ?pName
WHERE { 

# ?s ?p wd:Q750016 .
        
OPTIONAL {?s <http://schema.org/name> ?sName .}
OPTIONAL{?p <http://schema.org/name> ?pName .}
} 
ORDER BY ASC (?pName)
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('s', 'https://www.wikidata.org/wiki/Special:EntityData/Q750016'), ('p', 'http://schema.org/about')]
# [('s', 'http://www.wikidata.org/entity/Q27074'), ('sName', 'Aston Martin Lagonda'), ('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part')]
# [('s', 'http://www.wikidata.org/entity/Q42311'), ('sName', 'Sebastian Vettel'), ('p', 'http://www.wikidata.org/prop/direct/P54'), ('pName', 'member of sports team')]
# [('s', 'http://www.wikidata.org/entity/Q506657'), ('sName', 'Frédéric Makowiecki'), ('p', 'http://www.wikidata.org/prop/direct/P54'), ('pName', 'member of sports team')]
# [('s', 'http://www.wikidata.org/entity/Q23900707'), ('sName', 'Thiim-Sørensen-Turner'), ('p', 'http://www.wikidata.org/prop/direct/P361'), ('pName', 'part of')]
# [('s', 'http://www.wikidata.org/entity/Q23657686'), ('sName', '2016 FIA World Endurance Cup for GT Manufacturers'), ('p', 'http://www.wikidata.org/prop/direct/P710'), ('pName', 'participant')]
# [('s', 'http://www.wikidata.org/entity/Q21155426'), ('sName', '2016 FIA World Endurance Championship'), ('p', 'http://www.wikidata.org/prop/direct/P1923'), ('pName', 'participating team')]
# [('s', 'http://www.wikidata.org/entity/Q23900711'), ('sName', 'Aston Martin Vantage GTE'), ('p', 'http://www.wikidata.org/prop/direct/P1535'), ('pName', 'used by')]
# 8

# %% [markdown]
# Exploring RedBull Racing, using "part of" P361

# %%
queryString = """
SELECT ?p ?pName ?obj ?objName
WHERE { 

wd:Q173663 wdt:P361 ?obj   .
        
OPTIONAL {?obj <http://schema.org/name> ?objName .}
OPTIONAL{?p <http://schema.org/name> ?pName .}
} 
ORDER BY ASC (?pName)
"""

print("Results")
run_query(queryString)
# Out:
# Results
# Empty
# 0

# %%
queryString = """
SELECT ?obj ?objName
WHERE { 

wd:Q173663 wdt:P361 ?obj   .
        
OPTIONAL {?obj <http://schema.org/name> ?objName .}
OPTIONAL{?p <http://schema.org/name> ?pName .}
} 

"""

print("Results")
run_query(queryString)
# Out:
# Results
# Empty
# 0

# %%
queryString = """
SELECT ?p ?pName ?obj ?objName
WHERE { 

wd:Q173663 ?p ?obj   .
        
OPTIONAL {?obj <http://schema.org/name> ?objName .}
OPTIONAL{?p <http://schema.org/name> ?pName .}
} 

"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P641'), ('pName', 'sport'), ('obj', 'http://www.wikidata.org/entity/Q2705092'), ('objName', 'Formula One racing')]
# [('p', 'http://www.wikidata.org/prop/direct/P17'), ('pName', 'country'), ('obj', 'http://www.wikidata.org/entity/Q145'), ('objName', 'United Kingdom')]
# [('p', 'http://www.wikidata.org/prop/direct/P452'), ('pName', 'industry'), ('obj', 'http://www.wikidata.org/entity/Q190117'), ('objName', 'automotive industry')]
# [('p', 'http://www.wikidata.org/prop/direct/P641'), ('pName', 'sport'), ('obj', 'http://www.wikidata.org/entity/Q5386'), ('objName', 'auto racing')]
# [('p', 'http://www.wikidata.org/prop/direct/P127'), ('pName', 'owned by'), ('obj', 'http://www.wikidata.org/entity/Q698639'), ('objName', 'Red Bull GmbH')]
# [('p', 'http://www.wikidata.org/prop/direct/P740'), ('pName', 'location of formation'), ('obj', 'http://www.wikidata.org/entity/Q204234'), ('objName', 'Milton Keynes')]
# [('p', 'http://www.wikidata.org/prop/direct/P159'), ('pName', 'headquarters location'), ('obj', 'http://www.wikidata.org/entity/Q204234'), ('objName', 'Milton Keynes')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q10497835'), ('objName', 'Formula One team')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q20074337'), ('objName', 'auto racing team')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q12973014'), ('objName', 'sports team')]
# [('p', 'http://www.wikidata.org/prop/direct/P355'), ('pName', 'subsidiary'), ('obj', 'http://www.wikidata.org/entity/Q2079949'), ('objName', 'Red Bull Junior Team')]
# [('p', 'http://www.wikidata.org/prop/direct/P1056'), ('pName', 'product or material produced'), ('obj', 'http://www.wikidata.org/entity/Q16259746'), ('objName', 'transmission')]
# [('p', 'http://www.wikidata.org/prop/direct/P910'), ('pName', "topic's main category"), ('obj', 'http://www.wikidata.org/entity/Q8285721'), ('objName', 'Category:Red Bull Racing')]
# [('p', 'http://www.wikidata.org/prop/direct/P18'), ('pName', 'image'), ('obj', 'http://commons.wikimedia.org/wiki/Special:FilePath/Sebastian%20Vettel%20overtaking%20Mark%20Webber%202013%20Malaysia%202.jpg')]
# [('p', 'http://www.wikidata.org/prop/direct/P2002'), ('pName', 'Twitter username'), ('obj', 'redbullracing')]
# [('p', 'http://www.wikidata.org/prop/direct/P2003'), ('pName', 'Instagram username'), ('obj', 'redbullracing')]
# [('p', 'http://www.wikidata.org/prop/direct/P2013'), ('pName', 'Facebook ID'), ('obj', 'redbullracing')]
# [('p', 'http://www.wikidata.org/prop/direct/P2397'), ('pName', 'YouTube channel ID'), ('obj', 'UCQIyqMWCdx1GBvbw_Yi6lEA')]
# [('p', 'http://www.wikidata.org/prop/direct/P3417'), ('pName', 'Quora topic ID'), ('obj', 'Red-Bull-Racing')]
# [('p', 'http://www.wikidata.org/prop/direct/P373'), ('pName', 'Commons category'), ('obj', 'Red Bull Racing')]
# [('p', 'http://www.wikidata.org/prop/direct/P571'), ('pName', 'inception'), ('obj', '2005-01-01T00:00:00Z')]
# [('p', 'http://www.wikidata.org/prop/direct/P646'), ('pName', 'Freebase ID'), ('obj', '/m/04dd5t')]
# [('p', 'http://www.wikidata.org/prop/direct/P856'), ('pName', 'official website'), ('obj', 'https://www.redbull.com/int-en/redbullracing')]
# [('p', 'http://www.wikidata.org/prop/direct/P8672'), ('pName', 'Twitter topic ID'), ('obj', '854711040990248960')]
# [('p', 'http://www.wikidata.org/prop/direct/P8687'), ('pName', 'social media followers'), ('obj', '2766613')]
# [('p', 'http://www.wikidata.org/prop/direct/P8687'), ('pName', 'social media followers'), ('obj', '959000')]
# [('p', 'http://www.wikidata.org/prop/direct/P935'), ('pName', 'Commons gallery'), ('obj', 'Red Bull Racing')]
# [('p', 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), ('obj', 'http://wikiba.se/ontology#Item')]
# [('p', 'http://www.wikidata.org/prop/direct-normalized/P646'), ('obj', 'http://g.co/kg/m/04dd5t')]
# [('p', 'http://schema.org/name'), ('obj', 'Red Bull Racing')]
# 30

# %% [markdown]
# I've found an interesting property: P127 "owned by". Exploring ToroRosso Q141818 with this new info

# %%
queryString = """
SELECT ?p ?pName ?obj ?objName
WHERE { 

wd:Q141818 ?p ?obj   .
        
OPTIONAL {?obj <http://schema.org/name> ?objName .}
OPTIONAL{?p <http://schema.org/name> ?pName .}
} 

"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P641'), ('pName', 'sport'), ('obj', 'http://www.wikidata.org/entity/Q1968'), ('objName', 'Formula One')]
# [('p', 'http://www.wikidata.org/prop/direct/P17'), ('pName', 'country'), ('obj', 'http://www.wikidata.org/entity/Q38'), ('objName', 'Italy')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q10497835'), ('objName', 'Formula One team')]
# [('p', 'http://www.wikidata.org/prop/direct/P1366'), ('pName', 'replaced by'), ('obj', 'http://www.wikidata.org/entity/Q71371541'), ('objName', 'Scuderia AlphaTauri Grimm')]
# [('p', 'http://www.wikidata.org/prop/direct/P910'), ('pName', "topic's main category"), ('obj', 'http://www.wikidata.org/entity/Q8055888'), ('objName', 'Category:Scuderia Toro Rosso')]
# [('p', 'http://www.wikidata.org/prop/direct/P18'), ('pName', 'image'), ('obj', 'http://commons.wikimedia.org/wiki/Special:FilePath/Daniel%20Ricciardo%202013%20Malaysia%20FP2%201.jpg')]
# [('p', 'http://www.wikidata.org/prop/direct/P2002'), ('pName', 'Twitter username'), ('obj', 'tororosso')]
# [('p', 'http://www.wikidata.org/prop/direct/P2003'), ('pName', 'Instagram username'), ('obj', 'tororosso')]
# [('p', 'http://www.wikidata.org/prop/direct/P2013'), ('pName', 'Facebook ID'), ('obj', 'tororosso')]
# [('p', 'http://www.wikidata.org/prop/direct/P2397'), ('pName', 'YouTube channel ID'), ('obj', 'UCU56G7ZKkB7xkua6EhMz5dg')]
# [('p', 'http://www.wikidata.org/prop/direct/P3417'), ('pName', 'Quora topic ID'), ('obj', 'Scuderia-Toro-Rosso')]
# [('p', 'http://www.wikidata.org/prop/direct/P373'), ('pName', 'Commons category'), ('obj', 'Scuderia Toro Rosso')]
# [('p', 'http://www.wikidata.org/prop/direct/P571'), ('pName', 'inception'), ('obj', '2005-01-01T00:00:00Z')]
# [('p', 'http://www.wikidata.org/prop/direct/P646'), ('pName', 'Freebase ID'), ('obj', '/m/08c195')]
# [('p', 'http://www.wikidata.org/prop/direct/P856'), ('pName', 'official website'), ('obj', 'https://web.archive.org/web/20190524043938/https://scuderiatororosso.redbull.com/en/')]
# [('p', 'http://www.wikidata.org/prop/direct/P8687'), ('pName', 'social media followers'), ('obj', '206000')]
# [('p', 'http://www.wikidata.org/prop/direct/P935'), ('pName', 'Commons gallery'), ('obj', 'Scuderia Toro Rosso')]
# [('p', 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), ('obj', 'http://wikiba.se/ontology#Item')]
# [('p', 'http://www.wikidata.org/prop/direct-normalized/P646'), ('obj', 'http://g.co/kg/m/08c195')]
# [('p', 'http://schema.org/name'), ('obj', 'Scuderia Toro Rosso')]
# 20

# %% [markdown]
# Alpha Tauri?

# %%
queryString = """
SELECT ?p ?pName ?obj ?objName
WHERE { 

wd:Q71371541 ?p ?obj   .
        
OPTIONAL {?obj <http://schema.org/name> ?objName .}
OPTIONAL{?p <http://schema.org/name> ?pName .}
} 

"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P1365'), ('pName', 'replaces'), ('obj', 'http://www.wikidata.org/entity/Q141818'), ('objName', 'Scuderia Toro Rosso')]
# [('p', 'http://www.wikidata.org/prop/direct/P159'), ('pName', 'headquarters location'), ('obj', 'http://www.wikidata.org/entity/Q52981'), ('objName', 'Faenza')]
# [('p', 'http://www.wikidata.org/prop/direct/P17'), ('pName', 'country'), ('obj', 'http://www.wikidata.org/entity/Q38'), ('objName', 'Italy')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q10497835'), ('objName', 'Formula One team')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q21748148'), ('objName', 'Formula One constructor')]
# [('p', 'http://www.wikidata.org/prop/direct/P138'), ('pName', 'named after'), ('obj', 'http://www.wikidata.org/entity/Q60752400'), ('objName', 'AlphaTauri')]
# [('p', 'http://www.wikidata.org/prop/direct/P18'), ('pName', 'image'), ('obj', 'http://commons.wikimedia.org/wiki/Special:FilePath/2020%20Formula%20One%20tests%20Barcelona%2C%20AlphaTauri%20AT01%2C%20Pierre%20Gasly.jpg')]
# [('p', 'http://www.wikidata.org/prop/direct/P2002'), ('pName', 'Twitter username'), ('obj', 'AlphaTauriF1')]
# [('p', 'http://www.wikidata.org/prop/direct/P2003'), ('pName', 'Instagram username'), ('obj', 'alphataurif1')]
# [('p', 'http://www.wikidata.org/prop/direct/P2013'), ('pName', 'Facebook ID'), ('obj', 'alphataurif1')]
# [('p', 'http://www.wikidata.org/prop/direct/P2397'), ('pName', 'YouTube channel ID'), ('obj', 'UCU56G7ZKkB7xkua6EhMz5dg')]
# [('p', 'http://www.wikidata.org/prop/direct/P2671'), ('pName', 'Google Knowledge Graph ID'), ('obj', '/g/11fp03trlz')]
# [('p', 'http://www.wikidata.org/prop/direct/P373'), ('pName', 'Commons category'), ('obj', 'Scuderia AlphaTauri')]
# [('p', 'http://www.wikidata.org/prop/direct/P4264'), ('pName', 'LinkedIn company ID'), ('obj', 'alphataurif1')]
# [('p', 'http://www.wikidata.org/prop/direct/P571'), ('pName', 'inception'), ('obj', '2020-02-14T00:00:00Z')]
# [('p', 'http://www.wikidata.org/prop/direct/P856'), ('pName', 'official website'), ('obj', 'https://www.scuderiaalphatauri.com')]
# [('p', 'http://www.wikidata.org/prop/direct/P8672'), ('pName', 'Twitter topic ID'), ('obj', '854714182603755521')]
# [('p', 'http://www.wikidata.org/prop/direct/P8687'), ('pName', 'social media followers'), ('obj', '882621')]
# [('p', 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), ('obj', 'http://wikiba.se/ontology#Item')]
# [('p', 'http://www.wikidata.org/prop/direct-normalized/P2671'), ('obj', 'http://g.co/kg/g/11fp03trlz')]
# [('p', 'http://schema.org/name'), ('obj', 'Scuderia AlphaTauri Grimm')]
# 21

# %% [markdown]
# ToroRosso/Aplha Tauri are indipendet companies.

# %% [markdown]
# Looking for a driver Lance Stroll. But I don't see the property member of sport, like Vettel.

# %%
queryString = """
SELECT ?person ?pName
WHERE { 

# ?person wdt:P106 wd:Q10841764 .

OPTIONAL{?person <http://schema.org/name> ?pName .}
} 
ORDER BY DESC (?pName)
LIMIT 300
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('person', 'http://www.wikidata.org/entity/Q60837212')]
# [('person', 'http://www.wikidata.org/entity/Q85854161')]
# [('person', 'http://www.wikidata.org/entity/Q16140520')]
# [('person', 'http://www.wikidata.org/entity/Q61000367')]
# [('person', 'http://www.wikidata.org/entity/Q57451'), ('pName', 'Wolfgang von Trips')]
# [('person', 'http://www.wikidata.org/entity/Q61495'), ('pName', 'Wolfgang Seidel')]
# [('person', 'http://www.wikidata.org/entity/Q173296'), ('pName', 'Wilson Fittipaldi Júnior')]
# [('person', 'http://www.wikidata.org/entity/Q171881'), ('pName', 'Willy Mairesse')]
# [('person', 'http://www.wikidata.org/entity/Q2460525'), ('pName', 'William Ferguson')]
# [('person', 'http://www.wikidata.org/entity/Q172546'), ('pName', 'William Cantrell')]
# [('person', 'http://www.wikidata.org/entity/Q66177'), ('pName', 'Willi Krakau')]
# [('person', 'http://www.wikidata.org/entity/Q61486'), ('pName', 'Willi Heeks')]
# [('person', 'http://www.wikidata.org/entity/Q1866804'), ('pName', 'Willard Cantrell')]
# [('person', 'http://www.wikidata.org/entity/Q538467'), ('pName', 'Will Stevens')]
# [('person', 'http://www.wikidata.org/entity/Q2488720'), ('pName', 'Werner Bickel')]
# [('person', 'http://www.wikidata.org/entity/Q173669'), ('pName', 'Wayne Weiler')]
# [('person', 'http://www.wikidata.org/entity/Q1671761'), ('pName', 'Wayne Selser')]
# [('person', 'http://www.wikidata.org/entity/Q172412'), ('pName', 'Walt Hansgen')]
# [('person', 'http://www.wikidata.org/entity/Q173418'), ('pName', 'Walt Faulkner')]
# [('person', 'http://www.wikidata.org/entity/Q172561'), ('pName', 'Walt Brown')]
# [('person', 'http://www.wikidata.org/entity/Q165393'), ('pName', 'Walt Ader')]
# [('person', 'http://www.wikidata.org/entity/Q1919887'), ('pName', 'Wally Campbell')]
# [('person', 'http://www.wikidata.org/entity/Q60462'), ('pName', 'Volker Weidler')]
# [('person', 'http://www.wikidata.org/entity/Q171294'), ('pName', 'Vitantonio Liuzzi')]
# [('person', 'http://www.wikidata.org/entity/Q172486'), ('pName', 'Vic Wilson')]
# [('person', 'http://www.wikidata.org/entity/Q18068343'), ('pName', 'Vic Proctor')]
# [('person', 'http://www.wikidata.org/entity/Q173244'), ('pName', 'Vic Elford')]
# [('person', 'http://www.wikidata.org/entity/Q1955093'), ('pName', 'Van Johnson')]
# [('person', 'http://www.wikidata.org/entity/Q138745'), ('pName', 'Valtteri Bottas')]
# [('person', 'http://www.wikidata.org/entity/Q172165'), ('pName', 'Troy Ruttman')]
# [('person', 'http://www.wikidata.org/entity/Q173442'), ('pName', 'Trevor Taylor')]
# [('person', 'http://www.wikidata.org/entity/Q172515'), ('pName', 'Trevor Blokdyk')]
# [('person', 'http://www.wikidata.org/entity/Q172636'), ('pName', 'Travis Webb')]
# [('person', 'http://www.wikidata.org/entity/Q173160'), ('pName', 'Toranosuke Takagi')]
# [('person', 'http://www.wikidata.org/entity/Q509740'), ('pName', 'Tony Trimmer')]
# [('person', 'http://www.wikidata.org/entity/Q172361'), ('pName', 'Tony Settember')]
# [('person', 'http://www.wikidata.org/entity/Q172202'), ('pName', 'Tony Rolt')]
# [('person', 'http://www.wikidata.org/entity/Q172660'), ('pName', 'Tony Marsh')]
# [('person', 'http://www.wikidata.org/entity/Q171830'), ('pName', 'Tony Maggs')]
# [('person', 'http://www.wikidata.org/entity/Q2090291'), ('pName', 'Tony Lanfranchi')]
# [('person', 'http://www.wikidata.org/entity/Q2030593'), ('pName', 'Tony Jefferies')]
# [('person', 'http://www.wikidata.org/entity/Q172379'), ('pName', 'Tony Crook')]
# [('person', 'http://www.wikidata.org/entity/Q171481'), ('pName', 'Tony Brooks')]
# [('person', 'http://www.wikidata.org/entity/Q171490'), ('pName', 'Tony Brise')]
# [('person', 'http://www.wikidata.org/entity/Q2803326'), ('pName', 'Tony Bonadies')]
# [('person', 'http://www.wikidata.org/entity/Q172098'), ('pName', 'Tony Bettenhausen')]
# [('person', 'http://www.wikidata.org/entity/Q61832'), ('pName', 'Toni Ulmen')]
# [('person', 'http://www.wikidata.org/entity/Q2127039'), ('pName', 'Tommy Hinnershitz')]
# [('person', 'http://www.wikidata.org/entity/Q172167'), ('pName', 'Tommy Byrne')]
# [('person', 'http://www.wikidata.org/entity/Q172835'), ('pName', 'Tom Pryce')]
# [('person', 'http://www.wikidata.org/entity/Q2552718'), ('pName', 'Tom Pistone')]
# [('person', 'http://www.wikidata.org/entity/Q927200'), ('pName', 'Tom Jones')]
# [('person', 'http://www.wikidata.org/entity/Q172793'), ('pName', 'Tom Bridger')]
# [('person', 'http://www.wikidata.org/entity/Q76719'), ('pName', 'Timo Glock')]
# [('person', 'http://www.wikidata.org/entity/Q172268'), ('pName', 'Timmy Mayer')]
# [('person', 'http://www.wikidata.org/entity/Q172802'), ('pName', 'Tim Parnell')]
# [('person', 'http://www.wikidata.org/entity/Q172265'), ('pName', 'Tiff Needell')]
# [('person', 'http://www.wikidata.org/entity/Q172001'), ('pName', 'Tiago Monteiro')]
# [('person', 'http://www.wikidata.org/entity/Q3544896'), ('pName', 'Thomas Monarch')]
# [('person', 'http://www.wikidata.org/entity/Q172761'), ('pName', 'Thierry Boutsen')]
# [('person', 'http://www.wikidata.org/entity/Q61295'), ('pName', 'Theo Helfrich')]
# [('person', 'http://www.wikidata.org/entity/Q61918'), ('pName', 'Theo Fitzau')]
# [('person', 'http://www.wikidata.org/entity/Q172136'), ('pName', 'Teddy Pilette')]
# [('person', 'http://www.wikidata.org/entity/Q1192944'), ('pName', 'Ted Whiteaway')]
# [('person', 'http://www.wikidata.org/entity/Q1545787'), ('pName', 'Ted Duncan')]
# [('person', 'http://www.wikidata.org/entity/Q173720'), ('pName', 'Syd van der Vyver')]
# [('person', 'http://www.wikidata.org/entity/Q171961'), ('pName', 'Stuart Lewis-Evans')]
# [('person', 'http://www.wikidata.org/entity/Q1344577'), ('pName', 'Stoffel Vandoorne')]
# [('person', 'http://www.wikidata.org/entity/Q172728'), ('pName', 'Stirling Moss')]
# [('person', 'http://www.wikidata.org/entity/Q10374175'), ('pName', 'Stephen Watson')]
# [('person', 'http://www.wikidata.org/entity/Q657158'), ('pName', 'Stephen South')]
# [('person', 'http://www.wikidata.org/entity/Q57435'), ('pName', 'Stefan Bellof')]
# [('person', 'http://www.wikidata.org/entity/Q172094'), ('pName', 'Skip Barber')]
# [('person', 'http://www.wikidata.org/entity/Q173700'), ('pName', 'Shorty Templeman')]
# [('person', 'http://www.wikidata.org/entity/Q173689'), ('pName', 'Shane Summers')]
# [('person', 'http://www.wikidata.org/entity/Q172124'), ('pName', 'Sergio Mantovani')]
# [('person', 'http://www.wikidata.org/entity/Q42311'), ('pName', 'Sebastian Vettel')]
# [('person', 'http://www.wikidata.org/entity/Q171410'), ('pName', 'Scott Speed')]
# [('person', 'http://www.wikidata.org/entity/Q172311'), ('pName', 'Sam Posey')]
# [('person', 'http://www.wikidata.org/entity/Q172291'), ('pName', 'Sam Hanks')]
# [('person', 'http://www.wikidata.org/entity/Q153242'), ('pName', 'Sam Bird')]
# [('person', 'http://www.wikidata.org/entity/Q19301816'), ('pName', 'Salvador Fàbregas Bas')]
# [('person', 'http://www.wikidata.org/entity/Q2398460'), ('pName', 'Russ Klar')]
# [('person', 'http://www.wikidata.org/entity/Q4476878'), ('pName', 'Russ Congdon')]
# [('person', 'http://www.wikidata.org/entity/Q171783'), ('pName', 'Rupert Keegan')]
# [('person', 'http://www.wikidata.org/entity/Q61842'), ('pName', 'Rudolf Krause')]
# [('person', 'http://www.wikidata.org/entity/Q2232584'), ('pName', 'Roy Sherman')]
# [('person', 'http://www.wikidata.org/entity/Q171717'), ('pName', 'Roy Salvadori')]
# [('person', 'http://www.wikidata.org/entity/Q974837'), ('pName', 'Roy Newman')]
# [('person', 'http://www.wikidata.org/entity/Q172034'), ('pName', 'Ronnie Bucknum')]
# [('person', 'http://www.wikidata.org/entity/Q172479'), ('pName', 'Ron Flockhart')]
# [('person', 'http://www.wikidata.org/entity/Q82742'), ('pName', 'Romain Grosjean')]
# [('person', 'http://www.wikidata.org/entity/Q57925'), ('pName', 'Rolf Stommelen')]
# [('person', 'http://www.wikidata.org/entity/Q78495'), ('pName', 'Roland Ratzenberger')]
# [('person', 'http://www.wikidata.org/entity/Q171501'), ('pName', 'Roger Williamson')]
# [('person', 'http://www.wikidata.org/entity/Q172155'), ('pName', 'Roger Penske')]
# [('person', 'http://www.wikidata.org/entity/Q146857'), ('pName', 'Roger Laurent')]
# [('person', 'http://www.wikidata.org/entity/Q172224'), ('pName', 'Roelof Wunderink')]
# [('person', 'http://www.wikidata.org/entity/Q172810'), ('pName', 'Rodney Nuckey')]
# [('person', 'http://www.wikidata.org/entity/Q172475'), ('pName', 'Rodger Ward')]
# [('person', 'http://www.wikidata.org/entity/Q172427'), ('pName', 'Robin Widdows')]
# [('person', 'http://www.wikidata.org/entity/Q7352795'), ('pName', 'Robin Smith')]
# [('person', 'http://www.wikidata.org/entity/Q172369'), ('pName', 'Robin Montgomerie-Charrington')]
# [('person', 'http://www.wikidata.org/entity/Q171427'), ('pName', 'Roberto Moreno')]
# [('person', 'http://www.wikidata.org/entity/Q171777'), ('pName', 'Roberto Mieres')]
# [('person', 'http://www.wikidata.org/entity/Q977386'), ('pName', 'Roberto Merhi')]
# [('person', 'http://www.wikidata.org/entity/Q45223'), ('pName', 'Roberto Lippi')]
# [('person', 'http://www.wikidata.org/entity/Q172499'), ('pName', 'Roberto Bussinello')]
# [('person', 'http://www.wikidata.org/entity/Q172206'), ('pName', 'Roberto Bonomi')]
# [('person', 'http://www.wikidata.org/entity/Q172352'), ('pName', "Robert O'Brien")]
# [('person', 'http://www.wikidata.org/entity/Q160359'), ('pName', 'Robert Kubica')]
# [('person', 'http://www.wikidata.org/entity/Q173102'), ('pName', 'Robert Doornbos')]
# [('person', 'http://www.wikidata.org/entity/Q1862046'), ('pName', 'Rob Slotemaker')]
# [('person', 'http://www.wikidata.org/entity/Q173681'), ('pName', 'Rob Schroeder')]
# [('person', 'http://www.wikidata.org/entity/Q171460'), ('pName', 'Richie Ginther')]
# [('person', 'http://www.wikidata.org/entity/Q3058450'), ('pName', 'Richard Utley')]
# [('person', 'http://www.wikidata.org/entity/Q172182'), ('pName', 'Richard Robarts')]
# [('person', 'http://www.wikidata.org/entity/Q7326941'), ('pName', 'Richard Jones')]
# [('person', 'http://www.wikidata.org/entity/Q172194'), ('pName', 'Richard Attwood')]
# [('person', 'http://www.wikidata.org/entity/Q172759'), ('pName', 'Riccardo Patrese')]
# [('person', 'http://www.wikidata.org/entity/Q172229'), ('pName', 'Ricardo Zunino')]
# [('person', 'http://www.wikidata.org/entity/Q171766'), ('pName', 'Ricardo Rodríguez de la Vega')]
# [('person', 'http://www.wikidata.org/entity/Q2204979'), ('pName', 'Rex Easton')]
# [('person', 'http://www.wikidata.org/entity/Q172057'), ('pName', 'Reg Parnell')]
# [('person', 'http://www.wikidata.org/entity/Q2135984'), ('pName', 'Red Hamilton')]
# [('person', 'http://www.wikidata.org/entity/Q173439'), ('pName', 'Red Amick')]
# [('person', 'http://www.wikidata.org/entity/Q14594706'), ('pName', 'Ray Mallock')]
# [('person', 'http://www.wikidata.org/entity/Q925009'), ('pName', 'Ray Knepper')]
# [('person', 'http://www.wikidata.org/entity/Q173215'), ('pName', 'Ray Crawford')]
# [('person', 'http://www.wikidata.org/entity/Q2438891'), ('pName', 'Ray Allen')]
# [('person', 'http://www.wikidata.org/entity/Q2090395'), ('pName', 'Ralph Pratt')]
# [('person', 'http://www.wikidata.org/entity/Q2139024'), ('pName', 'Ralph Liguori')]
# [('person', 'http://www.wikidata.org/entity/Q171581'), ('pName', 'Ralph Firman')]
# [('person', 'http://www.wikidata.org/entity/Q75825'), ('pName', 'Ralf Schumacher')]
# [('person', 'http://www.wikidata.org/entity/Q171621'), ('pName', 'Piers Courage')]
# [('person', 'http://www.wikidata.org/entity/Q11816647'), ('pName', 'Pierre Gasly')]
# [('person', 'http://www.wikidata.org/entity/Q171444'), ('pName', 'Philippe Adams')]
# [('person', 'http://www.wikidata.org/entity/Q172449'), ('pName', 'Philip Fotheringham-Parker')]
# [('person', 'http://www.wikidata.org/entity/Q3112'), ('pName', 'Phil Hill')]
# [('person', 'http://www.wikidata.org/entity/Q1807265'), ('pName', 'Phil Cade')]
# [('person', 'http://www.wikidata.org/entity/Q172487'), ('pName', 'Peter de Klerk')]
# [('person', 'http://www.wikidata.org/entity/Q173049'), ('pName', 'Peter Whitehead')]
# [('person', 'http://www.wikidata.org/entity/Q172429'), ('pName', 'Peter Westbury')]
# [('person', 'http://www.wikidata.org/entity/Q171891'), ('pName', 'Peter Walker')]
# [('person', 'http://www.wikidata.org/entity/Q172806'), ('pName', 'Peter Ryan')]
# [('person', 'http://www.wikidata.org/entity/Q171535'), ('pName', 'Peter Revson')]
# [('person', 'http://www.wikidata.org/entity/Q1897313'), ('pName', 'Peter Hahn')]
# [('person', 'http://www.wikidata.org/entity/Q171511'), ('pName', 'Peter Gethin')]
# [('person', 'http://www.wikidata.org/entity/Q171483'), ('pName', 'Peter Collins')]
# [('person', 'http://www.wikidata.org/entity/Q172828'), ('pName', 'Peter Broeker')]
# [('person', 'http://www.wikidata.org/entity/Q173410'), ('pName', 'Peter Ashdown')]
# [('person', 'http://www.wikidata.org/entity/Q173456'), ('pName', 'Peter Arundell')]
# [('person', 'http://www.wikidata.org/entity/Q172196'), ('pName', 'Pete Lovely')]
# [('person', 'http://www.wikidata.org/entity/Q369348'), ('pName', 'Perry McCarthy')]
# [('person', 'http://www.wikidata.org/entity/Q2660993'), ('pName', 'Perry Grimm')]
# [('person', 'http://www.wikidata.org/entity/Q82924'), ('pName', 'Pedro de la Rosa')]
# [('person', 'http://www.wikidata.org/entity/Q171452'), ('pName', 'Pedro Rodríguez')]
# [('person', 'http://www.wikidata.org/entity/Q171555'), ('pName', 'Pedro Lamy')]
# [('person', 'http://www.wikidata.org/entity/Q456593'), ('pName', 'Pedro Chaves')]
# [('person', 'http://www.wikidata.org/entity/Q82768'), ('pName', 'Paul di Resta')]
# [('person', 'http://www.wikidata.org/entity/Q7153681'), ('pName', 'Paul Smith')]
# [('person', 'http://www.wikidata.org/entity/Q172655'), ('pName', 'Paul Russo')]
# [('person', 'http://www.wikidata.org/entity/Q60886'), ('pName', 'Paul Pietsch')]
# [('person', 'http://www.wikidata.org/entity/Q172557'), ('pName', 'Paul Goldsmith')]
# [('person', 'http://www.wikidata.org/entity/Q1744334'), ('pName', 'Paul Goacher')]
# [('person', 'http://www.wikidata.org/entity/Q173328'), ('pName', 'Paul Frère')]
# [('person', 'http://www.wikidata.org/entity/Q172551'), ('pName', 'Paul Emery')]
# [('person', 'http://www.wikidata.org/entity/Q172187'), ('pName', 'Patrick Nève')]
# [('person', 'http://www.wikidata.org/entity/Q84167'), ('pName', 'Patrick Friesacher')]
# [('person', 'http://www.wikidata.org/entity/Q961162'), ('pName', "Pat O'Connor")]
# [('person', 'http://www.wikidata.org/entity/Q172630'), ('pName', 'Pat Flaherty')]
# [('person', 'http://www.wikidata.org/entity/Q82845'), ('pName', 'Pastor Maldonado')]
# [('person', 'http://www.wikidata.org/entity/Q85762'), ('pName', 'Pascal Wehrlein')]
# [('person', 'http://www.wikidata.org/entity/Q172501'), ('pName', 'Paddy Driver')]
# [('person', 'http://www.wikidata.org/entity/Q171922'), ('pName', 'Paco Godia')]
# [('person', 'http://www.wikidata.org/entity/Q172418'), ('pName', 'Pablo Birger')]
# [('person', 'http://www.wikidata.org/entity/Q78582'), ('pName', 'Otto Stuppacher')]
# [('person', 'http://www.wikidata.org/entity/Q2199845'), ('pName', 'Ottis Stine')]
# [('person', 'http://www.wikidata.org/entity/Q62697'), ('pName', 'Oswald Karch')]
# [('person', 'http://www.wikidata.org/entity/Q20029868'), ('pName', 'Oscar Moore')]
# [('person', 'http://www.wikidata.org/entity/Q171620'), ('pName', 'Oscar Larrauri')]
# [('person', 'http://www.wikidata.org/entity/Q172084'), ('pName', 'Oscar Alfredo Gálvez')]
# [('person', 'http://www.wikidata.org/entity/Q171624'), ('pName', 'Onofre Marimón')]
# [('person', 'http://www.wikidata.org/entity/Q172142'), ('pName', 'Olivier Gendebien')]
# [('person', 'http://www.wikidata.org/entity/Q716324'), ('pName', 'Oliver Turvey')]
# [('person', 'http://www.wikidata.org/entity/Q1423402'), ('pName', 'Norm Houser')]
# [('person', 'http://www.wikidata.org/entity/Q2230283'), ('pName', 'Norm Hall')]
# [('person', 'http://www.wikidata.org/entity/Q173311'), ('pName', 'Norberto Fontana')]
# [('person', 'http://www.wikidata.org/entity/Q5099567'), ('pName', 'Noel Hillis')]
# [('person', 'http://www.wikidata.org/entity/Q78489'), ('pName', 'Niki Lauda')]
# [('person', 'http://www.wikidata.org/entity/Q10501'), ('pName', 'Nigel Mansell')]
# [('person', 'http://www.wikidata.org/entity/Q75820'), ('pName', 'Nico Rosberg')]
# [('person', 'http://www.wikidata.org/entity/Q75810'), ('pName', 'Nick Heidfeld')]
# [('person', 'http://www.wikidata.org/entity/Q172279'), ('pName', 'Neville Lederle')]
# [('person', 'http://www.wikidata.org/entity/Q1973020'), ('pName', 'Neal Carter')]
# [('person', 'http://www.wikidata.org/entity/Q172090'), ('pName', 'Nasif Estéfano')]
# [('person', 'http://www.wikidata.org/entity/Q173420'), ('pName', 'Mário de Araújo Cabral')]
# [('person', 'http://www.wikidata.org/entity/Q172588'), ('pName', 'Myron Fohr')]
# [('person', 'http://www.wikidata.org/entity/Q172143'), ('pName', 'Moisés Solana')]
# [('person', 'http://www.wikidata.org/entity/Q173721'), ('pName', 'Milt Fankhouser')]
# [('person', 'http://www.wikidata.org/entity/Q518344'), ('pName', 'Mikko Kozarowitzky')]
# [('person', 'http://www.wikidata.org/entity/Q172049'), ('pName', 'Mike Wilds')]
# [('person', 'http://www.wikidata.org/entity/Q172604'), ('pName', 'Mike Taylor')]
# [('person', 'http://www.wikidata.org/entity/Q171729'), ('pName', 'Mike Spence')]
# [('person', 'http://www.wikidata.org/entity/Q172570'), ('pName', 'Mike Sparken')]
# [('person', 'http://www.wikidata.org/entity/Q173707'), ('pName', 'Mike Salay')]
# [('person', 'http://www.wikidata.org/entity/Q172141'), ('pName', 'Mike Parkes')]
# [('person', 'http://www.wikidata.org/entity/Q2616011'), ('pName', 'Mike Oliver')]
# [('person', 'http://www.wikidata.org/entity/Q172300'), ('pName', 'Mike Nazaruk')]
# [('person', 'http://www.wikidata.org/entity/Q173657'), ('pName', 'Mike Magill')]
# [('person', 'http://www.wikidata.org/entity/Q173599'), ('pName', 'Mike MacDowel')]
# [('person', 'http://www.wikidata.org/entity/Q2104'), ('pName', 'Mike Hawthorn')]
# [('person', 'http://www.wikidata.org/entity/Q172606'), ('pName', 'Mike Harris')]
# [('person', 'http://www.wikidata.org/entity/Q173147'), ('pName', 'Mike Hailwood')]
# [('person', 'http://www.wikidata.org/entity/Q172357'), ('pName', 'Mike Fisher')]
# [('person', 'http://www.wikidata.org/entity/Q475176'), ('pName', 'Mike Burch')]
# [('person', 'http://www.wikidata.org/entity/Q171734'), ('pName', 'Mike Beuttler')]
# [('person', 'http://www.wikidata.org/entity/Q173094'), ('pName', 'Mika Salo')]
# [('person', 'http://www.wikidata.org/entity/Q172842'), ('pName', 'Mika Häkkinen')]
# [('person', 'http://www.wikidata.org/entity/Q172131'), ('pName', 'Miguel Ángel Guerra')]
# [('person', 'http://www.wikidata.org/entity/Q9671'), ('pName', 'Michael Schumacher')]
# [('person', 'http://www.wikidata.org/entity/Q172024'), ('pName', 'Michael Bleekemolen')]
# [('person', 'http://www.wikidata.org/entity/Q60897'), ('pName', 'Michael Bartels')]
# [('person', 'http://www.wikidata.org/entity/Q171519'), ('pName', 'Michael Andretti')]
# [('person', 'http://www.wikidata.org/entity/Q2239218'), ('pName', 'Max Verstappen')]
# [('person', 'http://www.wikidata.org/entity/Q613590'), ('pName', 'Max Chilton')]
# [('person', 'http://www.wikidata.org/entity/Q2709653'), ('pName', 'Mauritz von Strachwitz')]
# [('person', 'http://www.wikidata.org/entity/Q172305'), ('pName', 'Mauri Rose')]
# [('person', 'http://www.wikidata.org/entity/Q173421'), ('pName', 'Masten Gregory')]
# [('person', 'http://www.wikidata.org/entity/Q172624'), ('pName', 'Massimo Natili')]
# [('person', 'http://www.wikidata.org/entity/Q2281544'), ('pName', 'Marvin Pifer')]
# [('person', 'http://www.wikidata.org/entity/Q2054909'), ('pName', 'Marvin Burke')]
# [('person', 'http://www.wikidata.org/entity/Q171528'), ('pName', 'Martin Donnelly')]
# [('person', 'http://www.wikidata.org/entity/Q172854'), ('pName', 'Martin Brundle')]
# [('person', 'http://www.wikidata.org/entity/Q173569'), ('pName', 'Marshall Teague')]
# [('person', 'http://www.wikidata.org/entity/Q75841'), ('pName', 'Markus Winkelhock')]
# [('person', 'http://www.wikidata.org/entity/Q82667'), ('pName', 'Mark Webber')]
# [('person', 'http://www.wikidata.org/entity/Q1900215'), ('pName', 'Mark Light')]
# [('person', 'http://www.wikidata.org/entity/Q171732'), ('pName', 'Mark Donohue')]
# [('person', 'http://www.wikidata.org/entity/Q171553'), ('pName', 'Mark Blundell')]
# [('person', 'http://www.wikidata.org/entity/Q171312'), ('pName', 'Mario Andretti')]
# [('person', 'http://www.wikidata.org/entity/Q171572'), ('pName', 'Maria Teresa de Filippis')]
# [('person', 'http://www.wikidata.org/entity/Q172780'), ('pName', 'Marc Gené')]
# [('person', 'http://www.wikidata.org/entity/Q173076'), ('pName', 'Manny Ayulo')]
# [('person', 'http://www.wikidata.org/entity/Q57733'), ('pName', 'Manfred Winkelhock')]
# [('person', 'http://www.wikidata.org/entity/Q2152673'), ('pName', 'Manfred Mohr')]
# [('person', 'http://www.wikidata.org/entity/Q173584'), ('pName', 'Mack Hellings')]
# [('person', 'http://www.wikidata.org/entity/Q172646'), ('pName', 'Luki Botha')]
# [('person', 'http://www.wikidata.org/entity/Q172053'), ('pName', 'Luiz Bueno')]
# [('person', 'http://www.wikidata.org/entity/Q173379'), ('pName', 'Luis Pérez-Sala')]
# [('person', 'http://www.wikidata.org/entity/Q2253423'), ('pName', 'Ludwig Fischer')]
# [('person', 'http://www.wikidata.org/entity/Q171893'), ('pName', 'Lucien Bianchi')]
# [('person', 'http://www.wikidata.org/entity/Q172293'), ('pName', 'Lloyd Ruby')]
# [('person', 'http://www.wikidata.org/entity/Q1866907'), ('pName', 'Lloyd Casner')]
# [('person', 'http://www.wikidata.org/entity/Q9673'), ('pName', 'Lewis Hamilton')]
# [('person', 'http://www.wikidata.org/entity/Q172410'), ('pName', 'Leslie Thorne')]
# [('person', 'http://www.wikidata.org/entity/Q172117'), ('pName', 'Leslie Marr')]
# [('person', 'http://www.wikidata.org/entity/Q172208'), ('pName', 'Leslie Johnson')]
# [('person', 'http://www.wikidata.org/entity/Q172795'), ('pName', 'Les Leston')]
# [('person', 'http://www.wikidata.org/entity/Q553428'), ('pName', 'Leroy Warriner')]
# [('person', 'http://www.wikidata.org/entity/Q2679702'), ('pName', 'Leon Clum')]
# [('person', 'http://www.wikidata.org/entity/Q173325'), ('pName', 'Leo Kinnunen')]
# [('person', 'http://www.wikidata.org/entity/Q173674'), ('pName', 'Len Sutton')]
# [('person', 'http://www.wikidata.org/entity/Q172576'), ('pName', 'Len Duncan')]
# [('person', 'http://www.wikidata.org/entity/Q453022'), ('pName', 'Lee Wallard')]
# [('person', 'http://www.wikidata.org/entity/Q2940496'), ('pName', 'Lee Drollinger')]
# [('person', 'http://www.wikidata.org/entity/Q172578'), ('pName', 'Larry Crockett')]
# [('person', 'http://www.wikidata.org/entity/Q22007193'), ('pName', 'Lando Norris')]
# [('person', 'http://www.wikidata.org/entity/Q16238921'), ('pName', 'Lance Stroll')]
# [('person', 'http://www.wikidata.org/entity/Q172592'), ('pName', 'Lance Reventlow')]
# [('person', 'http://www.wikidata.org/entity/Q172199'), ('pName', 'Lance Macklin')]
# [('person', 'http://www.wikidata.org/entity/Q687734'), ('pName', 'Kurt Kuhnke')]
# [('person', 'http://www.wikidata.org/entity/Q26179112'), ('pName', 'Kurt Bardi-Barry')]
# [('person', 'http://www.wikidata.org/entity/Q60395'), ('pName', 'Kurt Ahrens')]
# [('person', 'http://www.wikidata.org/entity/Q61033'), ('pName', 'Kurt Adolff')]
# [('person', 'http://www.wikidata.org/entity/Q6419549'), ('pName', 'Klaas Twisk')]
# [('person', 'http://www.wikidata.org/entity/Q11192'), ('pName', 'Kimi Räikkönen')]
# [('person', 'http://www.wikidata.org/entity/Q552613'), ('pName', 'Kevin Cogan')]
# [('person', 'http://www.wikidata.org/entity/Q1685426'), ('pName', 'Kenny Eaton')]
# [('person', 'http://www.wikidata.org/entity/Q173261'), ('pName', 'Kenny Acheson')]
# [('person', 'http://www.wikidata.org/entity/Q172259'), ('pName', 'Kenneth McAlpine')]
# [('person', 'http://www.wikidata.org/entity/Q172452'), ('pName', 'Ken Wharton')]
# [('person', 'http://www.wikidata.org/entity/Q941105'), ('pName', 'Ken Richardson')]
# [('person', 'http://www.wikidata.org/entity/Q172344'), ('pName', 'Ken Downing')]
# [('person', 'http://www.wikidata.org/entity/Q171381'), ('pName', 'Keke Rosberg')]
# [('person', 'http://www.wikidata.org/entity/Q27966803'), ('pName', 'Keith St. John')]
# [('person', 'http://www.wikidata.org/entity/Q172815'), ('pName', 'Keith Greene')]
# [('person', 'http://www.wikidata.org/entity/Q173433'), ('pName', 'Keith Andrews')]
# [('person', 'http://www.wikidata.org/entity/Q84161'), ('pName', 'Karl Wendlinger')]
# [('person', 'http://www.wikidata.org/entity/Q875290'), ('pName', 'Karl Oppitzhauser')]
# [('person', 'http://www.wikidata.org/entity/Q63713'), ('pName', 'Karl Kling')]
# [('person', 'http://www.wikidata.org/entity/Q171996'), ('pName', "Jérôme d'Ambrosio")]
# [('person', 'http://www.wikidata.org/entity/Q171577'), ('pName', 'Justin Wilson')]
# [('person', 'http://www.wikidata.org/entity/Q173304'), ('pName', 'Julian Bailey')]
# [('person', 'http://www.wikidata.org/entity/Q172643'), ('pName', 'Jud Larson')]
# [('person', 'http://www.wikidata.org/entity/Q2069'), ('pName', 'Juan Manuel Fangio')]
# [('person', 'http://www.wikidata.org/entity/Q636886'), ('pName', 'Juan Manuel Bordeu')]
# [('person', 'http://www.wikidata.org/entity/Q290404'), ('pName', 'Juan Jover')]
# [('person', 'http://www.wikidata.org/entity/Q171447'), ('pName', 'José Froilán González')]
# [('person', 'http://www.wikidata.org/entity/Q171531'), ('pName', 'Joseph Siffert')]
# 300

# %%
queryString = """
SELECT ?p ?pName ?obj ?objName
WHERE { 

wd:Q16238921 ?p ?obj .

OPTIONAL{?p <http://schema.org/name> ?pName .}
OPTIONAL{?obj <http://schema.org/name> ?objName .}
} 
ORDER BY DESC (?pName)
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P641'), ('pName', 'sport'), ('obj', 'http://www.wikidata.org/entity/Q2705092'), ('objName', 'Formula One racing')]
# [('p', 'http://www.wikidata.org/prop/direct/P641'), ('pName', 'sport'), ('obj', 'http://www.wikidata.org/entity/Q5386'), ('objName', 'auto racing')]
# [('p', 'http://www.wikidata.org/prop/direct/P8687'), ('pName', 'social media followers'), ('obj', '128349')]
# [('p', 'http://www.wikidata.org/prop/direct/P21'), ('pName', 'sex or gender'), ('obj', 'http://www.wikidata.org/entity/Q6581097'), ('objName', 'male')]
# [('p', 'http://www.wikidata.org/prop/direct/P3048'), ('pName', 'racing-reference.info driver ID'), ('obj', 'Lance_Stroll')]
# [('p', 'http://www.wikidata.org/prop/direct/P19'), ('pName', 'place of birth'), ('obj', 'http://www.wikidata.org/entity/Q340'), ('objName', 'Montreal')]
# [('p', 'http://www.wikidata.org/prop/direct/P856'), ('pName', 'official website'), ('obj', 'https://www.lancestroll.com')]
# [('p', 'http://www.wikidata.org/prop/direct/P106'), ('pName', 'occupation'), ('obj', 'http://www.wikidata.org/entity/Q10841764'), ('objName', 'Formula One driver')]
# [('p', 'http://www.wikidata.org/prop/direct/P106'), ('pName', 'occupation'), ('obj', 'http://www.wikidata.org/entity/Q10349745'), ('objName', 'racing automobile driver')]
# [('p', 'http://www.wikidata.org/prop/direct/P103'), ('pName', 'native language'), ('obj', 'http://www.wikidata.org/entity/Q979914'), ('objName', 'Quebec French')]
# [('p', 'http://www.wikidata.org/prop/direct/P8140'), ('pName', 'motorsportstats.com driver ID'), ('obj', 'lance-stroll')]
# [('p', 'http://www.wikidata.org/prop/direct/P54'), ('pName', 'member of sports team'), ('obj', 'http://www.wikidata.org/entity/Q56245286'), ('objName', 'Racing Point F1 Team')]
# [('p', 'http://www.wikidata.org/prop/direct/P1412'), ('pName', 'languages spoken, written or signed'), ('obj', 'http://www.wikidata.org/entity/Q150'), ('objName', 'French')]
# [('p', 'http://www.wikidata.org/prop/direct/P1412'), ('pName', 'languages spoken, written or signed'), ('obj', 'http://www.wikidata.org/entity/Q1860'), ('objName', 'English')]
# [('p', 'http://www.wikidata.org/prop/direct/P1412'), ('pName', 'languages spoken, written or signed'), ('obj', 'http://www.wikidata.org/entity/Q979914'), ('objName', 'Quebec French')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q5'), ('objName', 'human')]
# [('p', 'http://www.wikidata.org/prop/direct/P18'), ('pName', 'image'), ('obj', 'http://commons.wikimedia.org/wiki/Special:FilePath/2019%20Formula%20One%20tests%20Barcelona%2C%20Stroll%20%2833376133178%29.jpg')]
# [('p', 'http://www.wikidata.org/prop/direct/P735'), ('pName', 'given name'), ('obj', 'http://www.wikidata.org/entity/Q1801787'), ('objName', 'Lance')]
# [('p', 'http://www.wikidata.org/prop/direct/P22'), ('pName', 'father'), ('obj', 'http://www.wikidata.org/entity/Q24053619'), ('objName', 'Lawrence Stroll')]
# [('p', 'http://www.wikidata.org/prop/direct/P734'), ('pName', 'family name'), ('obj', 'http://www.wikidata.org/entity/Q37468059'), ('objName', 'Stroll')]
# [('p', 'http://www.wikidata.org/prop/direct/P734'), ('pName', 'family name'), ('obj', 'http://www.wikidata.org/entity/Q37574551'), ('objName', 'Strulovitch')]
# [('p', 'http://www.wikidata.org/prop/direct/P172'), ('pName', 'ethnic group'), ('obj', 'http://www.wikidata.org/entity/Q2935829'), ('objName', 'English Canadian')]
# [('p', 'http://www.wikidata.org/prop/direct/P172'), ('pName', 'ethnic group'), ('obj', 'http://www.wikidata.org/entity/Q4882454'), ('objName', 'Belgian Canadians')]
# [('p', 'http://www.wikidata.org/prop/direct/P569'), ('pName', 'date of birth'), ('obj', '1998-10-29T00:00:00Z')]
# [('p', 'http://www.wikidata.org/prop/direct/P27'), ('pName', 'country of citizenship'), ('obj', 'http://www.wikidata.org/entity/Q16'), ('objName', 'Canada')]
# [('p', 'http://www.wikidata.org/prop/direct/P27'), ('pName', 'country of citizenship'), ('obj', 'http://www.wikidata.org/entity/Q31'), ('objName', 'Belgium')]
# [('p', 'http://www.wikidata.org/prop/direct/P1532'), ('pName', 'country for sport'), ('obj', 'http://www.wikidata.org/entity/Q16'), ('objName', 'Canada')]
# [('p', 'http://www.wikidata.org/prop/direct/P7859'), ('pName', 'WorldCat Identities ID'), ('obj', 'lccn-no2019046679')]
# [('p', 'http://www.wikidata.org/prop/direct/P214'), ('pName', 'VIAF ID'), ('obj', '280152563091315560002')]
# [('p', 'http://www.wikidata.org/prop/direct/P2002'), ('pName', 'Twitter username'), ('obj', 'lance_stroll')]
# [('p', 'http://www.wikidata.org/prop/direct/P5421'), ('pName', 'Trading Card Database person ID'), ('obj', '271011')]
# [('p', 'http://www.wikidata.org/prop/direct/P244'), ('pName', 'Library of Congress authority ID'), ('obj', 'no2019046679')]
# [('p', 'http://www.wikidata.org/prop/direct/P2003'), ('pName', 'Instagram username'), ('obj', 'lance_stroll')]
# [('p', 'http://www.wikidata.org/prop/direct/P646'), ('pName', 'Freebase ID'), ('obj', '/m/0102dn5j')]
# [('p', 'http://www.wikidata.org/prop/direct/P2013'), ('pName', 'Facebook ID'), ('obj', 'stroll.lance')]
# [('p', 'http://www.wikidata.org/prop/direct/P3684'), ('pName', 'Driver Database driver ID'), ('obj', 'lance-stroll')]
# [('p', 'http://www.wikidata.org/prop/direct/P373'), ('pName', 'Commons category'), ('obj', 'Lance Stroll')]
# [('p', 'http://www.wikidata.org/prop/direct/P3427'), ('pName', 'AS.com athlete ID'), ('obj', 'lance_stroll/37029')]
# [('p', 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), ('obj', 'http://wikiba.se/ontology#Item')]
# [('p', 'http://www.wikidata.org/prop/direct-normalized/P214'), ('obj', 'http://viaf.org/viaf/280152563091315560002')]
# [('p', 'http://www.wikidata.org/prop/direct-normalized/P244'), ('obj', 'https://id.loc.gov/authorities/names/no2019046679')]
# [('p', 'http://www.wikidata.org/prop/direct-normalized/P646'), ('obj', 'http://g.co/kg/m/0102dn5j')]
# [('p', 'http://schema.org/name'), ('obj', 'Lance Stroll')]
# 43

# %% [markdown]
# EXploring Racing Point, the old name of AMR

# %%
queryString = """
SELECT ?p ?pName ?obj ?objName
WHERE { 

wd:Q56245286 ?p ?obj .

OPTIONAL{?p <http://schema.org/name> ?pName .}
OPTIONAL{?obj <http://schema.org/name> ?objName .}
} 
ORDER BY DESC (?pName)
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P1424'), ('pName', "topic's main template"), ('obj', 'http://www.wikidata.org/entity/Q56265077'), ('objName', 'Template:Racing Point Force India')]
# [('p', 'http://www.wikidata.org/prop/direct/P910'), ('pName', "topic's main category"), ('obj', 'http://www.wikidata.org/entity/Q60882862'), ('objName', 'Category:Racing Point')]
# [('p', 'http://www.wikidata.org/prop/direct/P8687'), ('pName', 'social media followers'), ('obj', '1003380')]
# [('p', 'http://www.wikidata.org/prop/direct/P8687'), ('pName', 'social media followers'), ('obj', '154000')]
# [('p', 'http://www.wikidata.org/prop/direct/P1366'), ('pName', 'replaced by'), ('obj', 'http://www.wikidata.org/entity/Q104620704'), ('objName', 'Aston Martin F1 Team')]
# [('p', 'http://www.wikidata.org/prop/direct/P856'), ('pName', 'official website'), ('obj', 'https://web.archive.org/web/20201231080631/https://www.racingpointf1.com/')]
# [('p', 'http://www.wikidata.org/prop/direct/P154'), ('pName', 'logo image'), ('obj', 'http://commons.wikimedia.org/wiki/Special:FilePath/BWT%20Racing%20Point%20Logo.svg')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q10497835'), ('objName', 'Formula One team')]
# [('p', 'http://www.wikidata.org/prop/direct/P571'), ('pName', 'inception'), ('obj', '2018-01-01T00:00:00Z')]
# [('p', 'http://www.wikidata.org/prop/direct/P18'), ('pName', 'image'), ('obj', 'http://commons.wikimedia.org/wiki/Special:FilePath/2019%20Formula%20One%20tests%20Barcelona%2C%20Stroll%20%2847209286722%29.jpg')]
# [('p', 'http://www.wikidata.org/prop/direct/P159'), ('pName', 'headquarters location'), ('obj', 'http://www.wikidata.org/entity/Q339226'), ('objName', 'Silverstone')]
# [('p', 'http://www.wikidata.org/prop/direct/P1889'), ('pName', 'different from'), ('obj', 'http://www.wikidata.org/entity/Q138933'), ('objName', 'Force India')]
# [('p', 'http://www.wikidata.org/prop/direct/P17'), ('pName', 'country'), ('obj', 'http://www.wikidata.org/entity/Q145'), ('objName', 'United Kingdom')]
# [('p', 'http://www.wikidata.org/prop/direct/P2397'), ('pName', 'YouTube channel ID'), ('obj', 'UC8pLH6_Dz4QwKYE-dtcaxeg')]
# [('p', 'http://www.wikidata.org/prop/direct/P2002'), ('pName', 'Twitter username'), ('obj', 'RacingPointF1')]
# [('p', 'http://www.wikidata.org/prop/direct/P8672'), ('pName', 'Twitter topic ID'), ('obj', '1132043423186280448')]
# [('p', 'http://www.wikidata.org/prop/direct/P2003'), ('pName', 'Instagram username'), ('obj', 'racingpointf1')]
# [('p', 'http://www.wikidata.org/prop/direct/P2671'), ('pName', 'Google Knowledge Graph ID'), ('obj', '/g/11f9w1gz8c')]
# [('p', 'http://www.wikidata.org/prop/direct/P2013'), ('pName', 'Facebook ID'), ('obj', 'racingpointf1')]
# [('p', 'http://www.wikidata.org/prop/direct/P373'), ('pName', 'Commons category'), ('obj', 'Racing Point')]
# [('p', 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), ('obj', 'http://wikiba.se/ontology#Item')]
# [('p', 'http://www.wikidata.org/prop/direct-normalized/P2671'), ('obj', 'http://g.co/kg/g/11f9w1gz8c')]
# [('p', 'http://schema.org/name'), ('obj', 'Racing Point F1 Team')]
# 23

# %% [markdown]
# Scuderia Ferrari wd:Q169898

# %%
queryString = """
SELECT ?p ?pName ?obj ?objName
WHERE { 

wd:Q169898 ?p ?obj .

OPTIONAL{?p <http://schema.org/name> ?pName .}
OPTIONAL{?obj <http://schema.org/name> ?objName .}
} 
ORDER BY DESC (?pName)
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P910'), ('pName', "topic's main category"), ('obj', 'http://www.wikidata.org/entity/Q9256648'), ('objName', 'Category:Scuderia Ferrari')]
# [('p', 'http://www.wikidata.org/prop/direct/P355'), ('pName', 'subsidiary'), ('obj', 'http://www.wikidata.org/entity/Q5445262'), ('objName', 'Ferrari Driver Academy')]
# [('p', 'http://www.wikidata.org/prop/direct/P641'), ('pName', 'sport'), ('obj', 'http://www.wikidata.org/entity/Q5386'), ('objName', 'auto racing')]
# [('p', 'http://www.wikidata.org/prop/direct/P859'), ('pName', 'sponsor'), ('obj', 'http://www.wikidata.org/entity/Q659379'), ('objName', 'Mahle GmbH')]
# [('p', 'http://www.wikidata.org/prop/direct/P859'), ('pName', 'sponsor'), ('obj', 'http://www.wikidata.org/entity/Q14799'), ('objName', 'Lenovo')]
# [('p', 'http://www.wikidata.org/prop/direct/P859'), ('pName', 'sponsor'), ('obj', 'http://www.wikidata.org/entity/Q691958'), ('objName', 'Hublot')]
# [('p', 'http://www.wikidata.org/prop/direct/P859'), ('pName', 'sponsor'), ('obj', 'http://www.wikidata.org/entity/Q489943'), ('objName', 'Kaspersky')]
# [('p', 'http://www.wikidata.org/prop/direct/P859'), ('pName', 'sponsor'), ('obj', 'http://www.wikidata.org/entity/Q653941'), ('objName', 'Ray-Ban')]
# [('p', 'http://www.wikidata.org/prop/direct/P859'), ('pName', 'sponsor'), ('obj', 'http://www.wikidata.org/entity/Q806215'), ('objName', 'Banco Santander')]
# [('p', 'http://www.wikidata.org/prop/direct/P859'), ('pName', 'sponsor'), ('obj', 'http://www.wikidata.org/entity/Q20652532'), ('objName', 'Weichai Holding Group')]
# [('p', 'http://www.wikidata.org/prop/direct/P859'), ('pName', 'sponsor'), ('obj', 'http://www.wikidata.org/entity/Q3240764'), ('objName', 'Shell Oil Company')]
# [('p', 'http://www.wikidata.org/prop/direct/P859'), ('pName', 'sponsor'), ('obj', 'http://www.wikidata.org/entity/Q128896'), ('objName', 'Advanced Micro Devices')]
# [('p', 'http://www.wikidata.org/prop/direct/P8687'), ('pName', 'social media followers'), ('obj', '2867061')]
# [('p', 'http://www.wikidata.org/prop/direct/P8687'), ('pName', 'social media followers'), ('obj', '932000')]
# [('p', 'http://www.wikidata.org/prop/direct/P749'), ('pName', 'parent organization'), ('obj', 'http://www.wikidata.org/entity/Q27586'), ('objName', 'Ferrari')]
# [('p', 'http://www.wikidata.org/prop/direct/P856'), ('pName', 'official website'), ('obj', 'https://www.ferrari.com/formula1')]
# [('p', 'http://www.wikidata.org/prop/direct/P1448'), ('pName', 'official name'), ('obj', 'Scuderia Ferrari Mission Winnow')]
# [('p', 'http://www.wikidata.org/prop/direct/P1448'), ('pName', 'official name'), ('obj', 'Scuderia Ferrari')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q10497835'), ('objName', 'Formula One team')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q20074337'), ('objName', 'auto racing team')]
# [('p', 'http://www.wikidata.org/prop/direct/P571'), ('pName', 'inception'), ('obj', '1929-01-01T00:00:00Z')]
# [('p', 'http://www.wikidata.org/prop/direct/P18'), ('pName', 'image'), ('obj', 'http://commons.wikimedia.org/wiki/Special:FilePath/Sebastian%20Vettel-Ferrari-2019%20%285%29.jpg')]
# [('p', 'http://www.wikidata.org/prop/direct/P17'), ('pName', 'country'), ('obj', 'http://www.wikidata.org/entity/Q38'), ('objName', 'Italy')]
# [('p', 'http://www.wikidata.org/prop/direct/P2397'), ('pName', 'YouTube channel ID'), ('obj', 'UCd8iY-kEHtaB8qt8MH--zGw')]
# [('p', 'http://www.wikidata.org/prop/direct/P7859'), ('pName', 'WorldCat Identities ID'), ('obj', 'lccn-n97068634')]
# [('p', 'http://www.wikidata.org/prop/direct/P214'), ('pName', 'VIAF ID'), ('obj', '130358168')]
# [('p', 'http://www.wikidata.org/prop/direct/P2002'), ('pName', 'Twitter username'), ('obj', 'ScuderiaFerrari')]
# [('p', 'http://www.wikidata.org/prop/direct/P8672'), ('pName', 'Twitter topic ID'), ('obj', '854706572252987392')]
# [('p', 'http://www.wikidata.org/prop/direct/P4342'), ('pName', 'Store norske leksikon ID'), ('obj', 'Scuderia_Ferrari')]
# [('p', 'http://www.wikidata.org/prop/direct/P396'), ('pName', 'SBN author ID'), ('obj', 'IT\\ICCU\\MODV\\235346')]
# [('p', 'http://www.wikidata.org/prop/direct/P3417'), ('pName', 'Quora topic ID'), ('obj', 'Scuderia-Ferrari-2')]
# [('p', 'http://www.wikidata.org/prop/direct/P244'), ('pName', 'Library of Congress authority ID'), ('obj', 'n97068634')]
# [('p', 'http://www.wikidata.org/prop/direct/P2003'), ('pName', 'Instagram username'), ('obj', 'scuderiaferrari')]
# [('p', 'http://www.wikidata.org/prop/direct/P646'), ('pName', 'Freebase ID'), ('obj', '/m/0179v6')]
# [('p', 'http://www.wikidata.org/prop/direct/P2013'), ('pName', 'Facebook ID'), ('obj', 'ScuderiaFerrari')]
# [('p', 'http://www.wikidata.org/prop/direct/P935'), ('pName', 'Commons gallery'), ('obj', 'Scuderia Ferrari')]
# [('p', 'http://www.wikidata.org/prop/direct/P373'), ('pName', 'Commons category'), ('obj', 'Scuderia Ferrari')]
# [('p', 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), ('obj', 'http://wikiba.se/ontology#Item')]
# [('p', 'http://www.wikidata.org/prop/direct-normalized/P214'), ('obj', 'http://viaf.org/viaf/130358168')]
# [('p', 'http://www.wikidata.org/prop/direct-normalized/P244'), ('obj', 'https://id.loc.gov/authorities/names/n97068634')]
# [('p', 'http://www.wikidata.org/prop/direct-normalized/P646'), ('obj', 'http://g.co/kg/m/0179v6')]
# [('p', 'http://schema.org/name'), ('obj', 'Scuderia Ferrari')]
# 42

# %% [markdown]
# After many queries I've found the property "parent organization" P749
#
# I can start to produce the BGP for the second point:
#
# Starting from the driver that work for a team that is owned/controlled by another company.

# %%
queryString = """
SELECT DISTINCT ?sportTeam ?tName ?parentC ?cName
WHERE { 

# ?person wdt:P106 wd:Q10841764 ;
        wdt:P54 ?sportTeam .
# ?sportTeam ?p ?parentC .

OPTIONAL{?sportTeam <http://schema.org/name> ?tName .}
OPTIONAL{?parentC <http://schema.org/name> ?cName .}

FILTER (?p = wdt:P749 OR wdt:P127 OR wdt:361)
} 
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('sportTeam', 'http://www.wikidata.org/entity/Q22958306'), ('tName', 'Team ByKolles #4'), ('parentC', 'http://www.wikidata.org/entity/Q22936930'), ('cName', 'Le Mans Prototype 1')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q22958306'), ('tName', 'Team ByKolles #4'), ('parentC', 'http://www.wikidata.org/entity/Q23674434'), ('cName', 'ByKolles')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q22958306'), ('tName', 'Team ByKolles #4'), ('parentC', 'http://www.wikidata.org/entity/Q20074337'), ('cName', 'auto racing team')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q22958306'), ('tName', 'Team ByKolles #4'), ('parentC', 'http://www.wikidata.org/entity/Q18348695'), ('cName', '2015 FIA World Endurance Championship')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q2267054'), ('tName', 'Manor Motorsport'), ('parentC', 'http://www.wikidata.org/entity/Q145'), ('cName', 'United Kingdom')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q2267054'), ('tName', 'Manor Motorsport'), ('parentC', 'http://www.wikidata.org/entity/Q5367'), ('cName', 'motorsport')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q2267054'), ('tName', 'Manor Motorsport'), ('parentC', 'http://www.wikidata.org/entity/Q20074337'), ('cName', 'auto racing team')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q3500607'), ('tName', 'Klenk'), ('parentC', 'http://www.wikidata.org/entity/Q5367'), ('cName', 'motorsport')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q3500607'), ('tName', 'Klenk'), ('parentC', 'http://www.wikidata.org/entity/Q713750'), ('cName', 'West Germany')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q3500607'), ('tName', 'Klenk'), ('parentC', 'http://www.wikidata.org/entity/Q4438121'), ('cName', 'sports organization')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q3500607'), ('tName', 'Klenk'), ('parentC', 'http://www.wikidata.org/entity/Q18020684'), ('cName', 'Hans Klenk')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q141818'), ('tName', 'Scuderia Toro Rosso'), ('parentC', 'http://www.wikidata.org/entity/Q1968'), ('cName', 'Formula One')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q141818'), ('tName', 'Scuderia Toro Rosso'), ('parentC', 'http://www.wikidata.org/entity/Q38'), ('cName', 'Italy')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q141818'), ('tName', 'Scuderia Toro Rosso'), ('parentC', 'http://www.wikidata.org/entity/Q10497835'), ('cName', 'Formula One team')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q141818'), ('tName', 'Scuderia Toro Rosso'), ('parentC', 'http://www.wikidata.org/entity/Q71371541'), ('cName', 'Scuderia AlphaTauri Grimm')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q141818'), ('tName', 'Scuderia Toro Rosso'), ('parentC', 'http://www.wikidata.org/entity/Q8055888'), ('cName', 'Category:Scuderia Toro Rosso')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q173663'), ('tName', 'Red Bull Racing'), ('parentC', 'http://www.wikidata.org/entity/Q2705092'), ('cName', 'Formula One racing')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q173663'), ('tName', 'Red Bull Racing'), ('parentC', 'http://www.wikidata.org/entity/Q145'), ('cName', 'United Kingdom')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q173663'), ('tName', 'Red Bull Racing'), ('parentC', 'http://www.wikidata.org/entity/Q190117'), ('cName', 'automotive industry')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q173663'), ('tName', 'Red Bull Racing'), ('parentC', 'http://www.wikidata.org/entity/Q5386'), ('cName', 'auto racing')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q173663'), ('tName', 'Red Bull Racing'), ('parentC', 'http://www.wikidata.org/entity/Q698639'), ('cName', 'Red Bull GmbH')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q173663'), ('tName', 'Red Bull Racing'), ('parentC', 'http://www.wikidata.org/entity/Q204234'), ('cName', 'Milton Keynes')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q173663'), ('tName', 'Red Bull Racing'), ('parentC', 'http://www.wikidata.org/entity/Q10497835'), ('cName', 'Formula One team')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q173663'), ('tName', 'Red Bull Racing'), ('parentC', 'http://www.wikidata.org/entity/Q20074337'), ('cName', 'auto racing team')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q173663'), ('tName', 'Red Bull Racing'), ('parentC', 'http://www.wikidata.org/entity/Q12973014'), ('cName', 'sports team')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q173663'), ('tName', 'Red Bull Racing'), ('parentC', 'http://www.wikidata.org/entity/Q2079949'), ('cName', 'Red Bull Junior Team')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q173663'), ('tName', 'Red Bull Racing'), ('parentC', 'http://www.wikidata.org/entity/Q16259746'), ('cName', 'transmission')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q173663'), ('tName', 'Red Bull Racing'), ('parentC', 'http://www.wikidata.org/entity/Q8285721'), ('cName', 'Category:Red Bull Racing')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q10667466'), ('tName', 'Siffert Racing Team'), ('parentC', 'http://www.wikidata.org/entity/Q171531'), ('cName', 'Joseph Siffert')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q10667466'), ('tName', 'Siffert Racing Team'), ('parentC', 'http://www.wikidata.org/entity/Q20074337'), ('cName', 'auto racing team')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q142381'), ('tName', 'Minardi'), ('parentC', 'http://www.wikidata.org/entity/Q38'), ('cName', 'Italy')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q142381'), ('tName', 'Minardi'), ('parentC', 'http://www.wikidata.org/entity/Q10497835'), ('cName', 'Formula One team')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q142381'), ('tName', 'Minardi'), ('parentC', 'http://www.wikidata.org/entity/Q21748148'), ('cName', 'Formula One constructor')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q171992'), ('tName', 'Tyrrell Racing'), ('parentC', 'http://www.wikidata.org/entity/Q145'), ('cName', 'United Kingdom')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q171992'), ('tName', 'Tyrrell Racing'), ('parentC', 'http://www.wikidata.org/entity/Q10497835'), ('cName', 'Formula One team')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q171992'), ('tName', 'Tyrrell Racing'), ('parentC', 'http://www.wikidata.org/entity/Q20074337'), ('cName', 'auto racing team')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q172148'), ('tName', 'British Racing Partnership'), ('parentC', 'http://www.wikidata.org/entity/Q145'), ('cName', 'United Kingdom')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q172148'), ('tName', 'British Racing Partnership'), ('parentC', 'http://www.wikidata.org/entity/Q20074337'), ('cName', 'auto racing team')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q172974'), ('tName', 'Forti'), ('parentC', 'http://www.wikidata.org/entity/Q38'), ('cName', 'Italy')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q172974'), ('tName', 'Forti'), ('parentC', 'http://www.wikidata.org/entity/Q10497835'), ('cName', 'Formula One team')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q172974'), ('tName', 'Forti'), ('parentC', 'http://www.wikidata.org/entity/Q20074337'), ('cName', 'auto racing team')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q173003'), ('tName', 'Cooper Car Company'), ('parentC', 'http://www.wikidata.org/entity/Q145'), ('cName', 'United Kingdom')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q173003'), ('tName', 'Cooper Car Company'), ('parentC', 'http://www.wikidata.org/entity/Q190117'), ('cName', 'automotive industry')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q173003'), ('tName', 'Cooper Car Company'), ('parentC', 'http://www.wikidata.org/entity/Q20074337'), ('cName', 'auto racing team')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q173003'), ('tName', 'Cooper Car Company'), ('parentC', 'http://www.wikidata.org/entity/Q173814'), ('cName', 'John Cooper')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q173012'), ('tName', 'British Racing Motors'), ('parentC', 'http://www.wikidata.org/entity/Q1856022'), ('cName', 'Raymond Mays')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q173012'), ('tName', 'British Racing Motors'), ('parentC', 'http://www.wikidata.org/entity/Q145'), ('cName', 'United Kingdom')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q173012'), ('tName', 'British Racing Motors'), ('parentC', 'http://www.wikidata.org/entity/Q10497835'), ('cName', 'Formula One team')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q173012'), ('tName', 'British Racing Motors'), ('parentC', 'http://www.wikidata.org/entity/Q20074337'), ('cName', 'auto racing team')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q173104'), ('tName', 'RAM Racing'), ('parentC', 'http://www.wikidata.org/entity/Q145'), ('cName', 'United Kingdom')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q173104'), ('tName', 'RAM Racing'), ('parentC', 'http://www.wikidata.org/entity/Q20074337'), ('cName', 'auto racing team')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q173177'), ('tName', 'March Engineering'), ('parentC', 'http://www.wikidata.org/entity/Q145'), ('cName', 'United Kingdom')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q173177'), ('tName', 'March Engineering'), ('parentC', 'http://www.wikidata.org/entity/Q190117'), ('cName', 'automotive industry')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q173177'), ('tName', 'March Engineering'), ('parentC', 'http://www.wikidata.org/entity/Q786820'), ('cName', 'automobile manufacturer')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q173177'), ('tName', 'March Engineering'), ('parentC', 'http://www.wikidata.org/entity/Q10497835'), ('cName', 'Formula One team')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q173177'), ('tName', 'March Engineering'), ('parentC', 'http://www.wikidata.org/entity/Q20074337'), ('cName', 'auto racing team')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q173177'), ('tName', 'March Engineering'), ('parentC', 'http://www.wikidata.org/entity/Q557757'), ('cName', 'March')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q173177'), ('tName', 'March Engineering'), ('parentC', 'http://www.wikidata.org/entity/Q5592731'), ('cName', 'Graham Coaker')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q173177'), ('tName', 'March Engineering'), ('parentC', 'http://www.wikidata.org/entity/Q173246'), ('cName', 'Max Mosley')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q173177'), ('tName', 'March Engineering'), ('parentC', 'http://www.wikidata.org/entity/Q173850'), ('cName', 'Robin Herd')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q173177'), ('tName', 'March Engineering'), ('parentC', 'http://www.wikidata.org/entity/Q172273'), ('cName', 'Alan Rees')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q173222'), ('tName', 'Gordini'), ('parentC', 'http://www.wikidata.org/entity/Q142'), ('cName', 'France')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q173222'), ('tName', 'Gordini'), ('parentC', 'http://www.wikidata.org/entity/Q190117'), ('cName', 'automotive industry')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q173222'), ('tName', 'Gordini'), ('parentC', 'http://www.wikidata.org/entity/Q786820'), ('cName', 'automobile manufacturer')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q173222'), ('tName', 'Gordini'), ('parentC', 'http://www.wikidata.org/entity/Q6686'), ('cName', 'Renault')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q173222'), ('tName', 'Gordini'), ('parentC', 'http://www.wikidata.org/entity/Q20074337'), ('cName', 'auto racing team')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q173222'), ('tName', 'Gordini'), ('parentC', 'http://www.wikidata.org/entity/Q216844'), ('cName', 'Les Ulis')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q173222'), ('tName', 'Gordini'), ('parentC', 'http://www.wikidata.org/entity/Q2407259'), ('cName', 'Amedeo Gordini')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q173222'), ('tName', 'Gordini'), ('parentC', 'http://www.wikidata.org/entity/Q61909253'), ('cName', 'Gordini in Formula One')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q173415'), ('tName', 'Ensign Racing'), ('parentC', 'http://www.wikidata.org/entity/Q145'), ('cName', 'United Kingdom')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q173415'), ('tName', 'Ensign Racing'), ('parentC', 'http://www.wikidata.org/entity/Q20074337'), ('cName', 'auto racing team')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q173450'), ('tName', 'All American Racers'), ('parentC', 'http://www.wikidata.org/entity/Q171466'), ('cName', 'Dan Gurney')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q173450'), ('tName', 'All American Racers'), ('parentC', 'http://www.wikidata.org/entity/Q354043'), ('cName', 'Carroll Shelby')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q173450'), ('tName', 'All American Racers'), ('parentC', 'http://www.wikidata.org/entity/Q1968'), ('cName', 'Formula One')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q173450'), ('tName', 'All American Racers'), ('parentC', 'http://www.wikidata.org/entity/Q30'), ('cName', 'United States of America')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q173450'), ('tName', 'All American Racers'), ('parentC', 'http://www.wikidata.org/entity/Q5367'), ('cName', 'motorsport')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q173450'), ('tName', 'All American Racers'), ('parentC', 'http://www.wikidata.org/entity/Q49244'), ('cName', 'Santa Ana')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q173450'), ('tName', 'All American Racers'), ('parentC', 'http://www.wikidata.org/entity/Q20074337'), ('cName', 'auto racing team')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q173485'), ('tName', 'Aston Butterworth'), ('parentC', 'http://www.wikidata.org/entity/Q172641'), ('cName', 'Bill Aston')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q173485'), ('tName', 'Aston Butterworth'), ('parentC', 'http://www.wikidata.org/entity/Q4786635'), ('cName', 'Archie Butterworth')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q173485'), ('tName', 'Aston Butterworth'), ('parentC', 'http://www.wikidata.org/entity/Q145'), ('cName', 'United Kingdom')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q173485'), ('tName', 'Aston Butterworth'), ('parentC', 'http://www.wikidata.org/entity/Q190117'), ('cName', 'automotive industry')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q173485'), ('tName', 'Aston Butterworth'), ('parentC', 'http://www.wikidata.org/entity/Q20074337'), ('cName', 'auto racing team')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q173536'), ('tName', 'Connaught Engineering'), ('parentC', 'http://www.wikidata.org/entity/Q145'), ('cName', 'United Kingdom')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q173536'), ('tName', 'Connaught Engineering'), ('parentC', 'http://www.wikidata.org/entity/Q190117'), ('cName', 'automotive industry')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q173536'), ('tName', 'Connaught Engineering'), ('parentC', 'http://www.wikidata.org/entity/Q20074337'), ('cName', 'auto racing team')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q173769'), ('tName', 'Scuderia Filipinetti'), ('parentC', 'http://www.wikidata.org/entity/Q39'), ('cName', 'Switzerland')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q173769'), ('tName', 'Scuderia Filipinetti'), ('parentC', 'http://www.wikidata.org/entity/Q71'), ('cName', 'Geneva')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q173769'), ('tName', 'Scuderia Filipinetti'), ('parentC', 'http://www.wikidata.org/entity/Q20074337'), ('cName', 'auto racing team')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q174008'), ('tName', 'Caterham F1'), ('parentC', 'http://www.wikidata.org/entity/Q201782'), ('cName', 'Caterham')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q174008'), ('tName', 'Caterham F1'), ('parentC', 'http://www.wikidata.org/entity/Q833'), ('cName', 'Malaysia')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q174008'), ('tName', 'Caterham F1'), ('parentC', 'http://www.wikidata.org/entity/Q10497835'), ('cName', 'Formula One team')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q174008'), ('tName', 'Caterham F1'), ('parentC', 'http://www.wikidata.org/entity/Q20074337'), ('cName', 'auto racing team')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q179686'), ('tName', 'Chaparral Cars'), ('parentC', 'http://www.wikidata.org/entity/Q128321'), ('cName', 'Midland')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q179686'), ('tName', 'Chaparral Cars'), ('parentC', 'http://www.wikidata.org/entity/Q171960'), ('cName', 'Hap Sharp')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q179686'), ('tName', 'Chaparral Cars'), ('parentC', 'http://www.wikidata.org/entity/Q172282'), ('cName', 'Jim Hall')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q179686'), ('tName', 'Chaparral Cars'), ('parentC', 'http://www.wikidata.org/entity/Q30'), ('cName', 'United States of America')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q179686'), ('tName', 'Chaparral Cars'), ('parentC', 'http://www.wikidata.org/entity/Q5367'), ('cName', 'motorsport')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q179686'), ('tName', 'Chaparral Cars'), ('parentC', 'http://www.wikidata.org/entity/Q20074337'), ('cName', 'auto racing team')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q3001169'), ('tName', 'Team Lotus'), ('parentC', 'http://www.wikidata.org/entity/Q847017'), ('cName', 'sports club')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q3001169'), ('tName', 'Team Lotus'), ('parentC', 'http://www.wikidata.org/entity/Q173996'), ('cName', 'Team Lotus')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q3001169'), ('tName', 'Team Lotus'), ('parentC', 'http://www.wikidata.org/entity/Q173018'), ('cName', 'Lotus F1')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q3001169'), ('tName', 'Team Lotus'), ('parentC', 'http://www.wikidata.org/entity/Q25412278'), ('cName', 'Lotus in Formula One')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q3312686'), ('tName', 'Gilby Engineering'), ('parentC', 'http://www.wikidata.org/entity/Q145'), ('cName', 'United Kingdom')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q3312686'), ('tName', 'Gilby Engineering'), ('parentC', 'http://www.wikidata.org/entity/Q20074337'), ('cName', 'auto racing team')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q6792781'), ('tName', 'Maurer Motorsport (Germany)'), ('parentC', 'http://www.wikidata.org/entity/Q183'), ('cName', 'Germany')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q6792781'), ('tName', 'Maurer Motorsport (Germany)'), ('parentC', 'http://www.wikidata.org/entity/Q5367'), ('cName', 'motorsport')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q6792781'), ('tName', 'Maurer Motorsport (Germany)'), ('parentC', 'http://www.wikidata.org/entity/Q20074337'), ('cName', 'auto racing team')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q6792781'), ('tName', 'Maurer Motorsport (Germany)'), ('parentC', 'http://www.wikidata.org/entity/Q17100969'), ('cName', 'Maurer Motorsport')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q780447'), ('tName', 'Rob Walker Racing Team'), ('parentC', 'http://www.wikidata.org/entity/Q3128'), ('cName', 'Graham Hill')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q780447'), ('tName', 'Rob Walker Racing Team'), ('parentC', 'http://www.wikidata.org/entity/Q540333'), ('cName', 'Dorking')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q780447'), ('tName', 'Rob Walker Racing Team'), ('parentC', 'http://www.wikidata.org/entity/Q172728'), ('cName', 'Stirling Moss')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q780447'), ('tName', 'Rob Walker Racing Team'), ('parentC', 'http://www.wikidata.org/entity/Q145'), ('cName', 'United Kingdom')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q780447'), ('tName', 'Rob Walker Racing Team'), ('parentC', 'http://www.wikidata.org/entity/Q171531'), ('cName', 'Joseph Siffert')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q780447'), ('tName', 'Rob Walker Racing Team'), ('parentC', 'http://www.wikidata.org/entity/Q2125'), ('cName', 'Jack Brabham')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q780447'), ('tName', 'Rob Walker Racing Team'), ('parentC', 'http://www.wikidata.org/entity/Q20074337'), ('cName', 'auto racing team')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q780447'), ('tName', 'Rob Walker Racing Team'), ('parentC', 'http://www.wikidata.org/entity/Q171438'), ('cName', 'Maurice Trintignant')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q780447'), ('tName', 'Rob Walker Racing Team'), ('parentC', 'http://www.wikidata.org/entity/Q3234'), ('cName', 'Jochen Rindt')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q780447'), ('tName', 'Rob Walker Racing Team'), ('parentC', 'http://www.wikidata.org/entity/Q172239'), ('cName', 'Joakim Bonnier')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q622489'), ('tName', 'Alfa Romeo'), ('parentC', 'http://www.wikidata.org/entity/Q26921'), ('cName', 'Alfa Romeo')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q622489'), ('tName', 'Alfa Romeo'), ('parentC', 'http://www.wikidata.org/entity/Q38'), ('cName', 'Italy')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q622489'), ('tName', 'Alfa Romeo'), ('parentC', 'http://www.wikidata.org/entity/Q10497835'), ('cName', 'Formula One team')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q622489'), ('tName', 'Alfa Romeo'), ('parentC', 'http://www.wikidata.org/entity/Q171335'), ('cName', 'Sauber')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q622489'), ('tName', 'Alfa Romeo'), ('parentC', 'http://www.wikidata.org/entity/Q7943241'), ('cName', 'Category:Alfa Romeo Formula One drivers')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q622489'), ('tName', 'Alfa Romeo'), ('parentC', 'http://www.wikidata.org/entity/Q21748148'), ('cName', 'Formula One constructor')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q622489'), ('tName', 'Alfa Romeo'), ('parentC', 'http://www.wikidata.org/entity/Q65960697'), ('cName', 'Alfa Romeo in Formula One')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q22956606'), ('tName', 'Lotterer-Tréluyer-Fässler'), ('parentC', 'http://www.wikidata.org/entity/Q23663718'), ('cName', 'Audi Sport Team Joest')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q22956606'), ('tName', 'Lotterer-Tréluyer-Fässler'), ('parentC', 'http://www.wikidata.org/entity/Q20074337'), ('cName', 'auto racing team')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q22956606'), ('tName', 'Lotterer-Tréluyer-Fässler'), ('parentC', 'http://www.wikidata.org/entity/Q22940089'), ('cName', 'automobile endurance racing')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q22956606'), ('tName', 'Lotterer-Tréluyer-Fässler'), ('parentC', 'http://www.wikidata.org/entity/Q18348695'), ('cName', '2015 FIA World Endurance Championship')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q16300222'), ('tName', 'Haas F1 Team'), ('parentC', 'http://www.wikidata.org/entity/Q2705092'), ('cName', 'Formula One racing')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q16300222'), ('tName', 'Haas F1 Team'), ('parentC', 'http://www.wikidata.org/entity/Q145'), ('cName', 'United Kingdom')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q16300222'), ('tName', 'Haas F1 Team'), ('parentC', 'http://www.wikidata.org/entity/Q30'), ('cName', 'United States of America')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q16300222'), ('tName', 'Haas F1 Team'), ('parentC', 'http://www.wikidata.org/entity/Q10497835'), ('cName', 'Formula One team')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q16300222'), ('tName', 'Haas F1 Team'), ('parentC', 'http://www.wikidata.org/entity/Q30139025'), ('cName', 'Category:Haas Formula One drivers')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q171342'), ('tName', 'Honda'), ('parentC', 'http://www.wikidata.org/entity/Q1490'), ('cName', 'Tokyo')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q171342'), ('tName', 'Honda'), ('parentC', 'http://www.wikidata.org/entity/Q17'), ('cName', 'Japan')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q171342'), ('tName', 'Honda'), ('parentC', 'http://www.wikidata.org/entity/Q727'), ('cName', 'Amsterdam')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q171342'), ('tName', 'Honda'), ('parentC', 'http://www.wikidata.org/entity/Q211907'), ('cName', 'Slough')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q171342'), ('tName', 'Honda'), ('parentC', 'http://www.wikidata.org/entity/Q10497835'), ('cName', 'Formula One team')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q171342'), ('tName', 'Honda'), ('parentC', 'http://www.wikidata.org/entity/Q20074337'), ('cName', 'auto racing team')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q171342'), ('tName', 'Honda'), ('parentC', 'http://www.wikidata.org/entity/Q65961126'), ('cName', 'Honda in Formula One')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q169898'), ('tName', 'Scuderia Ferrari'), ('parentC', 'http://www.wikidata.org/entity/Q653941'), ('cName', 'Ray-Ban')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q169898'), ('tName', 'Scuderia Ferrari'), ('parentC', 'http://www.wikidata.org/entity/Q27586'), ('cName', 'Ferrari')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q169898'), ('tName', 'Scuderia Ferrari'), ('parentC', 'http://www.wikidata.org/entity/Q38'), ('cName', 'Italy')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q169898'), ('tName', 'Scuderia Ferrari'), ('parentC', 'http://www.wikidata.org/entity/Q5386'), ('cName', 'auto racing')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q169898'), ('tName', 'Scuderia Ferrari'), ('parentC', 'http://www.wikidata.org/entity/Q10497835'), ('cName', 'Formula One team')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q169898'), ('tName', 'Scuderia Ferrari'), ('parentC', 'http://www.wikidata.org/entity/Q20074337'), ('cName', 'auto racing team')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q169898'), ('tName', 'Scuderia Ferrari'), ('parentC', 'http://www.wikidata.org/entity/Q128896'), ('cName', 'Advanced Micro Devices')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q169898'), ('tName', 'Scuderia Ferrari'), ('parentC', 'http://www.wikidata.org/entity/Q14799'), ('cName', 'Lenovo')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q169898'), ('tName', 'Scuderia Ferrari'), ('parentC', 'http://www.wikidata.org/entity/Q806215'), ('cName', 'Banco Santander')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q169898'), ('tName', 'Scuderia Ferrari'), ('parentC', 'http://www.wikidata.org/entity/Q489943'), ('cName', 'Kaspersky')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q169898'), ('tName', 'Scuderia Ferrari'), ('parentC', 'http://www.wikidata.org/entity/Q3240764'), ('cName', 'Shell Oil Company')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q169898'), ('tName', 'Scuderia Ferrari'), ('parentC', 'http://www.wikidata.org/entity/Q5445262'), ('cName', 'Ferrari Driver Academy')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q169898'), ('tName', 'Scuderia Ferrari'), ('parentC', 'http://www.wikidata.org/entity/Q20652532'), ('cName', 'Weichai Holding Group')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q169898'), ('tName', 'Scuderia Ferrari'), ('parentC', 'http://www.wikidata.org/entity/Q691958'), ('cName', 'Hublot')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q169898'), ('tName', 'Scuderia Ferrari'), ('parentC', 'http://www.wikidata.org/entity/Q659379'), ('cName', 'Mahle GmbH')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q171329'), ('tName', 'Benetton Formula'), ('parentC', 'http://www.wikidata.org/entity/Q38'), ('cName', 'Italy')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q171329'), ('tName', 'Benetton Formula'), ('parentC', 'http://www.wikidata.org/entity/Q10497835'), ('cName', 'Formula One team')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q171329'), ('tName', 'Benetton Formula'), ('parentC', 'http://www.wikidata.org/entity/Q20074337'), ('cName', 'auto racing team')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q171337'), ('tName', 'Williams Grand Prix Engineering'), ('parentC', 'http://www.wikidata.org/entity/Q15648574'), ('cName', 'racecar constructor')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q171337'), ('tName', 'Williams Grand Prix Engineering'), ('parentC', 'http://www.wikidata.org/entity/Q991626'), ('cName', 'Grove')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q171337'), ('tName', 'Williams Grand Prix Engineering'), ('parentC', 'http://www.wikidata.org/entity/Q167269'), ('cName', 'Patrick Head')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q171337'), ('tName', 'Williams Grand Prix Engineering'), ('parentC', 'http://www.wikidata.org/entity/Q145'), ('cName', 'United Kingdom')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q171337'), ('tName', 'Williams Grand Prix Engineering'), ('parentC', 'http://www.wikidata.org/entity/Q1968'), ('cName', 'Formula One')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q171337'), ('tName', 'Williams Grand Prix Engineering'), ('parentC', 'http://www.wikidata.org/entity/Q173214'), ('cName', 'Frank Williams')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q171337'), ('tName', 'Williams Grand Prix Engineering'), ('parentC', 'http://www.wikidata.org/entity/Q10497835'), ('cName', 'Formula One team')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q171337'), ('tName', 'Williams Grand Prix Engineering'), ('parentC', 'http://www.wikidata.org/entity/Q20074337'), ('cName', 'auto racing team')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q171337'), ('tName', 'Williams Grand Prix Engineering'), ('parentC', 'http://www.wikidata.org/entity/Q173225'), ('cName', 'Frank Williams Racing Cars')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q171337'), ('tName', 'Williams Grand Prix Engineering'), ('parentC', 'http://www.wikidata.org/entity/Q98714466'), ('cName', 'Dorilton Capital')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q22958306'), ('tName', 'Team ByKolles #4'), ('parentC', 'http://wikiba.se/ontology#Item')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q22958306'), ('tName', 'Team ByKolles #4'), ('parentC', '4')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q2267054'), ('tName', 'Manor Motorsport'), ('parentC', 'http://wikiba.se/ontology#Item')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q2267054'), ('tName', 'Manor Motorsport'), ('parentC', 'http://g.co/kg/m/03mc8vw')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q2267054'), ('tName', 'Manor Motorsport'), ('parentC', 'ManorWEC')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q2267054'), ('tName', 'Manor Motorsport'), ('parentC', 'realManor')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q2267054'), ('tName', 'Manor Motorsport'), ('parentC', 'Manor Motorsport')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q2267054'), ('tName', 'Manor Motorsport'), ('parentC', '1990-01-01T00:00:00Z')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q2267054'), ('tName', 'Manor Motorsport'), ('parentC', '/m/03mc8vw')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q2267054'), ('tName', 'Manor Motorsport'), ('parentC', 'http://manorf1team.com/')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q3500607'), ('tName', 'Klenk'), ('parentC', 'http://wikiba.se/ontology#Item')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q3500607'), ('tName', 'Klenk'), ('parentC', 'http://g.co/kg/m/04kxp4')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q3500607'), ('tName', 'Klenk'), ('parentC', '1954-01-01T00:00:00Z')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q3500607'), ('tName', 'Klenk'), ('parentC', '/m/04kxp4')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q141818'), ('tName', 'Scuderia Toro Rosso'), ('parentC', 'http://wikiba.se/ontology#Item')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q141818'), ('tName', 'Scuderia Toro Rosso'), ('parentC', 'http://g.co/kg/m/08c195')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q141818'), ('tName', 'Scuderia Toro Rosso'), ('parentC', 'http://commons.wikimedia.org/wiki/Special:FilePath/Daniel%20Ricciardo%202013%20Malaysia%20FP2%201.jpg')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q141818'), ('tName', 'Scuderia Toro Rosso'), ('parentC', 'tororosso')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q141818'), ('tName', 'Scuderia Toro Rosso'), ('parentC', 'UCU56G7ZKkB7xkua6EhMz5dg')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q141818'), ('tName', 'Scuderia Toro Rosso'), ('parentC', 'Scuderia-Toro-Rosso')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q141818'), ('tName', 'Scuderia Toro Rosso'), ('parentC', 'Scuderia Toro Rosso')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q141818'), ('tName', 'Scuderia Toro Rosso'), ('parentC', '2005-01-01T00:00:00Z')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q141818'), ('tName', 'Scuderia Toro Rosso'), ('parentC', '/m/08c195')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q141818'), ('tName', 'Scuderia Toro Rosso'), ('parentC', 'https://web.archive.org/web/20190524043938/https://scuderiatororosso.redbull.com/en/')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q141818'), ('tName', 'Scuderia Toro Rosso'), ('parentC', '206000')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q173663'), ('tName', 'Red Bull Racing'), ('parentC', 'http://wikiba.se/ontology#Item')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q173663'), ('tName', 'Red Bull Racing'), ('parentC', 'http://g.co/kg/m/04dd5t')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q173663'), ('tName', 'Red Bull Racing'), ('parentC', 'http://commons.wikimedia.org/wiki/Special:FilePath/Sebastian%20Vettel%20overtaking%20Mark%20Webber%202013%20Malaysia%202.jpg')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q173663'), ('tName', 'Red Bull Racing'), ('parentC', 'redbullracing')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q173663'), ('tName', 'Red Bull Racing'), ('parentC', 'UCQIyqMWCdx1GBvbw_Yi6lEA')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q173663'), ('tName', 'Red Bull Racing'), ('parentC', 'Red-Bull-Racing')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q173663'), ('tName', 'Red Bull Racing'), ('parentC', 'Red Bull Racing')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q173663'), ('tName', 'Red Bull Racing'), ('parentC', '2005-01-01T00:00:00Z')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q173663'), ('tName', 'Red Bull Racing'), ('parentC', '/m/04dd5t')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q173663'), ('tName', 'Red Bull Racing'), ('parentC', 'https://www.redbull.com/int-en/redbullracing')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q173663'), ('tName', 'Red Bull Racing'), ('parentC', '854711040990248960')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q173663'), ('tName', 'Red Bull Racing'), ('parentC', '959000')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q173663'), ('tName', 'Red Bull Racing'), ('parentC', '2766613')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q10667466'), ('tName', 'Siffert Racing Team'), ('parentC', 'http://wikiba.se/ontology#Item')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q142381'), ('tName', 'Minardi'), ('parentC', 'http://wikiba.se/ontology#Item')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q142381'), ('tName', 'Minardi'), ('parentC', 'http://g.co/kg/m/0b2pn')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q142381'), ('tName', 'Minardi'), ('parentC', 'http://commons.wikimedia.org/wiki/Special:FilePath/Minardi%20PS05%20British%20GP%202005.jpg')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q142381'), ('tName', 'Minardi'), ('parentC', 'Minardi')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q142381'), ('tName', 'Minardi'), ('parentC', '/m/0b2pn')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q171992'), ('tName', 'Tyrrell Racing'), ('parentC', 'http://wikiba.se/ontology#Item')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q171992'), ('tName', 'Tyrrell Racing'), ('parentC', 'http://g.co/kg/m/01y6jm')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q171992'), ('tName', 'Tyrrell Racing'), ('parentC', 'http://commons.wikimedia.org/wiki/Special:FilePath/Tyrrell.png')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q171992'), ('tName', 'Tyrrell Racing'), ('parentC', 'Tyrrell Racing')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q171992'), ('tName', 'Tyrrell Racing'), ('parentC', '1958-01-01T00:00:00Z')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q171992'), ('tName', 'Tyrrell Racing'), ('parentC', '/m/01y6jm')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q171992'), ('tName', 'Tyrrell Racing'), ('parentC', 'http://www.teamtyrrell.com/')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q172148'), ('tName', 'British Racing Partnership'), ('parentC', 'http://wikiba.se/ontology#Item')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q172148'), ('tName', 'British Racing Partnership'), ('parentC', 'http://g.co/kg/m/04n6b2')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q172148'), ('tName', 'British Racing Partnership'), ('parentC', 'British Racing Partnership')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q172148'), ('tName', 'British Racing Partnership'), ('parentC', '/m/04n6b2')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q172974'), ('tName', 'Forti'), ('parentC', 'http://wikiba.se/ontology#Item')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q172974'), ('tName', 'Forti'), ('parentC', 'http://g.co/kg/m/04k2_j')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q172974'), ('tName', 'Forti'), ('parentC', 'http://commons.wikimedia.org/wiki/Special:FilePath/Roberto%20Moreno%20Forti%201995%20Britain%20%28crop%29.jpg')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q172974'), ('tName', 'Forti'), ('parentC', '1978-01-01T00:00:00Z')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q172974'), ('tName', 'Forti'), ('parentC', '/m/04k2_j')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q173003'), ('tName', 'Cooper Car Company'), ('parentC', 'http://wikiba.se/ontology#Item')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q173003'), ('tName', 'Cooper Car Company'), ('parentC', 'http://viaf.org/viaf/239643875')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q173003'), ('tName', 'Cooper Car Company'), ('parentC', 'http://g.co/kg/m/02k8zp')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q173003'), ('tName', 'Cooper Car Company'), ('parentC', '239643875')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q173003'), ('tName', 'Cooper Car Company'), ('parentC', 'Cooper Car Company')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q173003'), ('tName', 'Cooper Car Company'), ('parentC', '/m/02k8zp')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q173003'), ('tName', 'Cooper Car Company'), ('parentC', 'viaf-239643875')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q173012'), ('tName', 'British Racing Motors'), ('parentC', 'http://wikiba.se/ontology#Item')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q173012'), ('tName', 'British Racing Motors'), ('parentC', 'http://viaf.org/viaf/149318528')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q173012'), ('tName', 'British Racing Motors'), ('parentC', 'https://id.loc.gov/authorities/names/no2008175661')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q173012'), ('tName', 'British Racing Motors'), ('parentC', 'http://g.co/kg/m/03km8x')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q173012'), ('tName', 'British Racing Motors'), ('parentC', 'http://commons.wikimedia.org/wiki/Special:FilePath/Rodriguez%2C%20Pedro%20-%20BRM%201968.jpg')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q173012'), ('tName', 'British Racing Motors'), ('parentC', '149318528')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q173012'), ('tName', 'British Racing Motors'), ('parentC', 'no2008175661')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q173012'), ('tName', 'British Racing Motors'), ('parentC', 'British Racing Motors')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q173012'), ('tName', 'British Racing Motors'), ('parentC', '1945-01-01T00:00:00Z')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q173012'), ('tName', 'British Racing Motors'), ('parentC', '/m/03km8x')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q173012'), ('tName', 'British Racing Motors'), ('parentC', 'lccn-no2008175661')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q173104'), ('tName', 'RAM Racing'), ('parentC', 'http://wikiba.se/ontology#Item')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q173104'), ('tName', 'RAM Racing'), ('parentC', 'http://g.co/kg/m/04lt7n')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q173104'), ('tName', 'RAM Racing'), ('parentC', 'RAM F1 cars')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q173104'), ('tName', 'RAM Racing'), ('parentC', '/m/04lt7n')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q173177'), ('tName', 'March Engineering'), ('parentC', 'http://wikiba.se/ontology#Item')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q173177'), ('tName', 'March Engineering'), ('parentC', 'http://g.co/kg/m/04vlct')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q173177'), ('tName', 'March Engineering'), ('parentC', 'March Engineering')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q173177'), ('tName', 'March Engineering'), ('parentC', '1969-01-01T00:00:00Z')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q173177'), ('tName', 'March Engineering'), ('parentC', '/m/04vlct')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q173222'), ('tName', 'Gordini'), ('parentC', 'http://wikiba.se/ontology#Item')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q173222'), ('tName', 'Gordini'), ('parentC', 'http://g.co/kg/m/04k2w6')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q173222'), ('tName', 'Gordini'), ('parentC', 'http://commons.wikimedia.org/wiki/Special:FilePath/Gordini%20Logo.svg')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q173222'), ('tName', 'Gordini'), ('parentC', 'Gordini vehicles')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q173222'), ('tName', 'Gordini'), ('parentC', '1946-01-01T00:00:00Z')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q173222'), ('tName', 'Gordini'), ('parentC', '/m/04k2w6')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q173415'), ('tName', 'Ensign Racing'), ('parentC', 'http://wikiba.se/ontology#Item')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q173415'), ('tName', 'Ensign Racing'), ('parentC', 'http://g.co/kg/m/04n6dl')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q173415'), ('tName', 'Ensign Racing'), ('parentC', 'Ensign F1 cars')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q173415'), ('tName', 'Ensign Racing'), ('parentC', '/m/04n6dl')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q173450'), ('tName', 'All American Racers'), ('parentC', 'http://wikiba.se/ontology#Item')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q173450'), ('tName', 'All American Racers'), ('parentC', 'http://g.co/kg/m/04vlcf')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q173450'), ('tName', 'All American Racers'), ('parentC', 'http://commons.wikimedia.org/wiki/Special:FilePath/Eagle%20Weslake%20T1G%20at%20Goodwood%20Revival%202012.jpg')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q173450'), ('tName', 'All American Racers'), ('parentC', 'All American Racers')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q173450'), ('tName', 'All American Racers'), ('parentC', '1964-01-01T00:00:00Z')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q173450'), ('tName', 'All American Racers'), ('parentC', '/m/04vlcf')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q173450'), ('tName', 'All American Racers'), ('parentC', 'http://www.allamericanracers.com/')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q173485'), ('tName', 'Aston Butterworth'), ('parentC', 'http://wikiba.se/ontology#Item')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q173485'), ('tName', 'Aston Butterworth'), ('parentC', 'http://g.co/kg/m/04n6v5')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q173485'), ('tName', 'Aston Butterworth'), ('parentC', '1952-01-01T00:00:00Z')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q173485'), ('tName', 'Aston Butterworth'), ('parentC', '1954-01-01T00:00:00Z')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q173485'), ('tName', 'Aston Butterworth'), ('parentC', '/m/04n6v5')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q173536'), ('tName', 'Connaught Engineering'), ('parentC', 'http://wikiba.se/ontology#Item')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q173536'), ('tName', 'Connaught Engineering'), ('parentC', 'http://g.co/kg/m/04n6bs')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q173536'), ('tName', 'Connaught Engineering'), ('parentC', 'Connaught racing cars')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q173536'), ('tName', 'Connaught Engineering'), ('parentC', '/m/04n6bs')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q173769'), ('tName', 'Scuderia Filipinetti'), ('parentC', 'http://wikiba.se/ontology#Item')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q173769'), ('tName', 'Scuderia Filipinetti'), ('parentC', 'http://g.co/kg/m/04y9rff')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q173769'), ('tName', 'Scuderia Filipinetti'), ('parentC', '/m/04y9rff')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q174008'), ('tName', 'Caterham F1'), ('parentC', 'http://wikiba.se/ontology#Item')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q174008'), ('tName', 'Caterham F1'), ('parentC', 'http://g.co/kg/m/0hzrxf2')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q174008'), ('tName', 'Caterham F1'), ('parentC', 'http://commons.wikimedia.org/wiki/Special:FilePath/Caterham%20F1%20Team%20logo.jpg')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q174008'), ('tName', 'Caterham F1'), ('parentC', 'http://commons.wikimedia.org/wiki/Special:FilePath/F1%202013%20Barcelona%20test%202%20-%20Caterham.jpg')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q174008'), ('tName', 'Caterham F1'), ('parentC', 'mycaterhamf1')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q174008'), ('tName', 'Caterham F1'), ('parentC', 'Caterham-F1-Team')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q174008'), ('tName', 'Caterham F1'), ('parentC', 'Caterham F1 Team')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q174008'), ('tName', 'Caterham F1'), ('parentC', '/m/0hzrxf2')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q174008'), ('tName', 'Caterham F1'), ('parentC', 'http://www.caterhamf1.com')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q179686'), ('tName', 'Chaparral Cars'), ('parentC', 'http://wikiba.se/ontology#Item')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q179686'), ('tName', 'Chaparral Cars'), ('parentC', 'http://g.co/kg/m/06zpnb')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q179686'), ('tName', 'Chaparral Cars'), ('parentC', 'http://commons.wikimedia.org/wiki/Special:FilePath/Bonnier%2C%20Chaparral%202D%2C%201966-06-03%20%28Sp%29.jpg')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q179686'), ('tName', 'Chaparral Cars'), ('parentC', '3886')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q179686'), ('tName', 'Chaparral Cars'), ('parentC', 'Chaparral')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q179686'), ('tName', 'Chaparral Cars'), ('parentC', 'Chaparral racing cars')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q179686'), ('tName', 'Chaparral Cars'), ('parentC', '1962-01-01T00:00:00Z')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q179686'), ('tName', 'Chaparral Cars'), ('parentC', '/m/06zpnb')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q179686'), ('tName', 'Chaparral Cars'), ('parentC', 'http://www.chaparralcars.com/')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q3001169'), ('tName', 'Team Lotus'), ('parentC', 'http://wikiba.se/ontology#Item')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q3001169'), ('tName', 'Team Lotus'), ('parentC', 'http://g.co/kg/m/07sbt75')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q3001169'), ('tName', 'Team Lotus'), ('parentC', 'http://commons.wikimedia.org/wiki/Special:FilePath/F1%202011%20Jerez%20day%203-7%20%28cropped%29.jpg')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q3001169'), ('tName', 'Team Lotus'), ('parentC', 'Team Lotus (2010-2011)')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q3001169'), ('tName', 'Team Lotus'), ('parentC', '/m/07sbt75')]
# ...
# [('sportTeam', 'http://www.wikidata.org/entity/Q957511'), ('tName', 'Fry'), ('parentC', 'http://wikiba.se/ontology#Item')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q957511'), ('tName', 'Fry'), ('parentC', 'http://g.co/kg/m/04n6gl')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q957511'), ('tName', 'Fry'), ('parentC', '/m/04n6gl')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q957511'), ('tName', 'Fry'), ('parentC', 'Fry')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q172197'), ('tName', 'Maki Engineering'), ('parentC', 'http://wikiba.se/ontology#Item')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q172197'), ('tName', 'Maki Engineering'), ('parentC', 'http://g.co/kg/m/04n6kf')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q172197'), ('tName', 'Maki Engineering'), ('parentC', 'Maki Engineering')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q172197'), ('tName', 'Maki Engineering'), ('parentC', '/m/04n6kf')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q172197'), ('tName', 'Maki Engineering'), ('parentC', 'Maki Engineering')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q7388751'), ('tName', 'SARD'), ('parentC', 'http://wikiba.se/ontology#Item')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q7388751'), ('tName', 'SARD'), ('parentC', 'http://g.co/kg/m/02vxsw4')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q7388751'), ('tName', 'SARD'), ('parentC', '1180301018284')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q7388751'), ('tName', 'SARD'), ('parentC', 'SARD')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q7388751'), ('tName', 'SARD'), ('parentC', '1985-01-01T00:00:00Z')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q7388751'), ('tName', 'SARD'), ('parentC', '/m/02vxsw4')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q7388751'), ('tName', 'SARD'), ('parentC', 'http://www.sard.co.jp/')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q7388751'), ('tName', 'SARD'), ('parentC', 'SARD')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q7439400'), ('tName', 'Scuderia Veloce'), ('parentC', 'http://wikiba.se/ontology#Item')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q7439400'), ('tName', 'Scuderia Veloce'), ('parentC', 'http://g.co/kg/m/09ggqwq')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q7439400'), ('tName', 'Scuderia Veloce'), ('parentC', '/m/09ggqwq')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q7439400'), ('tName', 'Scuderia Veloce'), ('parentC', 'Scuderia Veloce')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q38384815'), ('tName', 'Lotterer-Jani-Tandy'), ('parentC', 'http://wikiba.se/ontology#Item')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q38384815'), ('tName', 'Lotterer-Jani-Tandy'), ('parentC', '1')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q38384815'), ('tName', 'Lotterer-Jani-Tandy'), ('parentC', 'Lotterer-Jani-Tandy')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q98930155'), ('tName', 'Alpine F1 Team'), ('parentC', 'http://wikiba.se/ontology#Item')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q98930155'), ('tName', 'Alpine F1 Team'), ('parentC', 'http://g.co/kg/g/11k83n23l4')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q98930155'), ('tName', 'Alpine F1 Team'), ('parentC', 'Alpine F1 Team')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q98930155'), ('tName', 'Alpine F1 Team'), ('parentC', 'http://commons.wikimedia.org/wiki/Special:FilePath/Alpine%20F1%20Team%20Logo.svg')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q98930155'), ('tName', 'Alpine F1 Team'), ('parentC', 'AlpineF1Team')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q98930155'), ('tName', 'Alpine F1 Team'), ('parentC', 'alpinef1team')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q98930155'), ('tName', 'Alpine F1 Team'), ('parentC', 'UCzH4Iwlm8kI09wXbgHvFfIg')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q98930155'), ('tName', 'Alpine F1 Team'), ('parentC', '/g/11k83n23l4')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q98930155'), ('tName', 'Alpine F1 Team'), ('parentC', 'Alpine F1 Team')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q98930155'), ('tName', 'Alpine F1 Team'), ('parentC', 'alpine-cars')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q98930155'), ('tName', 'Alpine F1 Team'), ('parentC', 'https://www.alpinecars.com/en/formula-1/news')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q98930155'), ('tName', 'Alpine F1 Team'), ('parentC', '18400')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q98930155'), ('tName', 'Alpine F1 Team'), ('parentC', '1469363')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q14913969'), ('tName', 'Derrington-Francis'), ('parentC', 'http://wikiba.se/ontology#Item')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q14913969'), ('tName', 'Derrington-Francis'), ('parentC', 'http://g.co/kg/m/04n6d7')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q14913969'), ('tName', 'Derrington-Francis'), ('parentC', '/m/04n6d7')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q14913969'), ('tName', 'Derrington-Francis'), ('parentC', 'Derrington-Francis')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q172997'), ('tName', 'Walter Wolf Racing'), ('parentC', 'http://wikiba.se/ontology#Item')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q172997'), ('tName', 'Walter Wolf Racing'), ('parentC', 'http://g.co/kg/m/04ky06')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q172997'), ('tName', 'Walter Wolf Racing'), ('parentC', 'http://commons.wikimedia.org/wiki/Special:FilePath/Wolf%20WR6%20Mont-Tremblant%20Scheckter.jpg')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q172997'), ('tName', 'Walter Wolf Racing'), ('parentC', 'Walter Wolf Racing')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q172997'), ('tName', 'Walter Wolf Racing'), ('parentC', '/m/04ky06')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q172997'), ('tName', 'Walter Wolf Racing'), ('parentC', 'Walter Wolf Racing')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q173553'), ('tName', 'Emeryson'), ('parentC', 'http://wikiba.se/ontology#Item')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q173553'), ('tName', 'Emeryson'), ('parentC', 'http://g.co/kg/m/04kwjt')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q173553'), ('tName', 'Emeryson'), ('parentC', '/m/04kwjt')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q173553'), ('tName', 'Emeryson'), ('parentC', 'Emeryson')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q4893753'), ('tName', 'Bernard White Racing'), ('parentC', 'http://wikiba.se/ontology#Item')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q4893753'), ('tName', 'Bernard White Racing'), ('parentC', 'http://g.co/kg/m/0gjbq5n')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q4893753'), ('tName', 'Bernard White Racing'), ('parentC', '/m/0gjbq5n')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q4893753'), ('tName', 'Bernard White Racing'), ('parentC', 'Bernard White Racing')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q22939728'), ('tName', 'Bernhard-Webber-Hartley'), ('parentC', 'http://wikiba.se/ontology#Item')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q22939728'), ('tName', 'Bernhard-Webber-Hartley'), ('parentC', '1')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q22939728'), ('tName', 'Bernhard-Webber-Hartley'), ('parentC', 'Bernhard-Webber-Hartley')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q14905784'), ('tName', 'Wolf Racing Cars'), ('parentC', 'http://wikiba.se/ontology#Item')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q14905784'), ('tName', 'Wolf Racing Cars'), ('parentC', 'http://g.co/kg/m/0vxglns')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q14905784'), ('tName', 'Wolf Racing Cars'), ('parentC', '2009-01-01T00:00:00Z')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q14905784'), ('tName', 'Wolf Racing Cars'), ('parentC', '/m/0vxglns')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q14905784'), ('tName', 'Wolf Racing Cars'), ('parentC', 'http://www.wolfracingcars.com/')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q14905784'), ('tName', 'Wolf Racing Cars'), ('parentC', 'Wolf Racing Cars')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q173301'), ('tName', 'Embassy Hill'), ('parentC', 'http://wikiba.se/ontology#Item')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q173301'), ('tName', 'Embassy Hill'), ('parentC', 'http://g.co/kg/m/06rwcf')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q173301'), ('tName', 'Embassy Hill'), ('parentC', 'http://commons.wikimedia.org/wiki/Special:FilePath/HillGraham1969Aug.jpg')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q173301'), ('tName', 'Embassy Hill'), ('parentC', 'Embassy Hill')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q173301'), ('tName', 'Embassy Hill'), ('parentC', '1973-01-01T00:00:00Z')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q173301'), ('tName', 'Embassy Hill'), ('parentC', '1975-01-01T00:00:00Z')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q173301'), ('tName', 'Embassy Hill'), ('parentC', '/m/06rwcf')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q173301'), ('tName', 'Embassy Hill'), ('parentC', 'Embassy Hill')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q936574'), ('tName', 'O.S.C.A.'), ('parentC', 'http://wikiba.se/ontology#Item')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q936574'), ('tName', 'O.S.C.A.'), ('parentC', 'http://viaf.org/viaf/237050961')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q936574'), ('tName', 'O.S.C.A.'), ('parentC', 'http://g.co/kg/m/025t7_p')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q936574'), ('tName', 'O.S.C.A.'), ('parentC', 'http://commons.wikimedia.org/wiki/Special:FilePath/Emblem%20Osca.JPG')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q936574'), ('tName', 'O.S.C.A.'), ('parentC', '237050961')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q936574'), ('tName', 'O.S.C.A.'), ('parentC', 'OSCA')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q936574'), ('tName', 'O.S.C.A.'), ('parentC', '1947-01-01T00:00:00Z')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q936574'), ('tName', 'O.S.C.A.'), ('parentC', '1967-01-01T00:00:00Z')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q936574'), ('tName', 'O.S.C.A.'), ('parentC', '/m/025t7_p')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q936574'), ('tName', 'O.S.C.A.'), ('parentC', 'viaf-237050961')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q936574'), ('tName', 'O.S.C.A.'), ('parentC', 'O.S.C.A.')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q3220251'), ('tName', 'Equipe Ligier'), ('parentC', 'http://wikiba.se/ontology#Item')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q3220251'), ('tName', 'Equipe Ligier'), ('parentC', 'http://g.co/kg/m/080l53s')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q3220251'), ('tName', 'Equipe Ligier'), ('parentC', 'Ligier F1 cars')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q3220251'), ('tName', 'Equipe Ligier'), ('parentC', '1969-01-01T00:00:00Z')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q3220251'), ('tName', 'Equipe Ligier'), ('parentC', '1996-01-01T00:00:00Z')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q3220251'), ('tName', 'Equipe Ligier'), ('parentC', '/m/080l53s')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q3220251'), ('tName', 'Equipe Ligier'), ('parentC', 'Equipe Ligier')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q173093'), ('tName', 'Vanwall'), ('parentC', 'http://wikiba.se/ontology#Item')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q173093'), ('tName', 'Vanwall'), ('parentC', 'http://g.co/kg/m/029cc1')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q173093'), ('tName', 'Vanwall'), ('parentC', 'http://commons.wikimedia.org/wiki/Special:FilePath/Thinwall%20special.jpg')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q173093'), ('tName', 'Vanwall'), ('parentC', 'Vanwall F1 cars')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q173093'), ('tName', 'Vanwall'), ('parentC', '/m/029cc1')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q173093'), ('tName', 'Vanwall'), ('parentC', 'http://www.wikidata.org/entity/Q28470086')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q173093'), ('tName', 'Vanwall'), ('parentC', 'Vanwall')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q173093'), ('tName', 'Vanwall'), ('parentC', 'Vanwall')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q2291349'), ('tName', 'LEC Refrigeration Racing'), ('parentC', 'http://wikiba.se/ontology#Item')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q2291349'), ('tName', 'LEC Refrigeration Racing'), ('parentC', 'http://g.co/kg/m/04n6jd')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q2291349'), ('tName', 'LEC Refrigeration Racing'), ('parentC', '/m/04n6jd')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q2291349'), ('tName', 'LEC Refrigeration Racing'), ('parentC', 'LEC Refrigeration Racing')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q7439399'), ('tName', 'Scuderia Scribante'), ('parentC', 'http://wikiba.se/ontology#Item')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q7439399'), ('tName', 'Scuderia Scribante'), ('parentC', 'http://g.co/kg/m/0j26pcs')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q7439399'), ('tName', 'Scuderia Scribante'), ('parentC', '/m/0j26pcs')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q7439399'), ('tName', 'Scuderia Scribante'), ('parentC', 'Scuderia Scribante')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q6411971'), ('tName', 'King Racing'), ('parentC', 'http://wikiba.se/ontology#Item')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q6411971'), ('tName', 'King Racing'), ('parentC', 'http://g.co/kg/m/09nx3d')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q6411971'), ('tName', 'King Racing'), ('parentC', '1986-01-01T00:00:00Z')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q6411971'), ('tName', 'King Racing'), ('parentC', '/m/09nx3d')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q6411971'), ('tName', 'King Racing'), ('parentC', 'King Racing')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q5483924'), ('tName', 'Van Amersfoort Racing'), ('parentC', 'http://wikiba.se/ontology#Item')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q5483924'), ('tName', 'Van Amersfoort Racing'), ('parentC', 'http://g.co/kg/m/09g97tt')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q5483924'), ('tName', 'Van Amersfoort Racing'), ('parentC', 'http://commons.wikimedia.org/wiki/Special:FilePath/Recardo%20Bruins%20Choi.JPG')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q5483924'), ('tName', 'Van Amersfoort Racing'), ('parentC', 'VARmotorsport')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q5483924'), ('tName', 'Van Amersfoort Racing'), ('parentC', 'Van Amersfoort Racing')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q5483924'), ('tName', 'Van Amersfoort Racing'), ('parentC', '1975-01-01T00:00:00Z')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q5483924'), ('tName', 'Van Amersfoort Racing'), ('parentC', '/m/09g97tt')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q5483924'), ('tName', 'Van Amersfoort Racing'), ('parentC', 'http://www.vanamersfoortracing.nl/')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q5483924'), ('tName', 'Van Amersfoort Racing'), ('parentC', '6159')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q5483924'), ('tName', 'Van Amersfoort Racing'), ('parentC', 'Van Amersfoort Racing')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q2548586'), ('tName', 'Scuderia Ambrosiana'), ('parentC', 'http://wikiba.se/ontology#Item')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q2548586'), ('tName', 'Scuderia Ambrosiana'), ('parentC', 'http://g.co/kg/m/052559m')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q2548586'), ('tName', 'Scuderia Ambrosiana'), ('parentC', 'Scuderia Ambrosiana')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q2548586'), ('tName', 'Scuderia Ambrosiana'), ('parentC', '/m/052559m')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q2548586'), ('tName', 'Scuderia Ambrosiana'), ('parentC', 'Scuderia Ambrosiana')]
# 1573

# %% [markdown]
# Too vague. I need to change something

# %%
queryString = """
SELECT DISTINCT ?sportTeam ?tName ?parentC ?cName
WHERE { 

# ?person wdt:P106 wd:Q10841764 ;
        wdt:P54 ?sportTeam .
# ?sportTeam ?p ?parentC .

OPTIONAL{?sportTeam <http://schema.org/name> ?tName .}
OPTIONAL{?parentC <http://schema.org/name> ?cName .}

FILTER (?p = wdt:P749)
} 
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('sportTeam', 'http://www.wikidata.org/entity/Q173222'), ('tName', 'Gordini'), ('parentC', 'http://www.wikidata.org/entity/Q6686'), ('cName', 'Renault')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q169898'), ('tName', 'Scuderia Ferrari'), ('parentC', 'http://www.wikidata.org/entity/Q27586'), ('cName', 'Ferrari')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q172030'), ('tName', 'McLaren'), ('parentC', 'http://www.wikidata.org/entity/Q173146'), ('cName', 'McLaren Technology Group')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q23317'), ('tName', 'Audi'), ('parentC', 'http://www.wikidata.org/entity/Q156578'), ('cName', 'Volkswagen Group')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q40993'), ('tName', 'Porsche'), ('parentC', 'http://www.wikidata.org/entity/Q156578'), ('cName', 'Volkswagen Group')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q173314'), ('tName', 'Enzo Coloni Racing Car Systems'), ('parentC', 'http://www.wikidata.org/entity/Q1631454'), ('cName', 'Scuderia Coloni')]
# 6

# %%
queryString = """
SELECT DISTINCT ?sportTeam ?tName ?parentC ?cName
WHERE { 

# ?person wdt:P106 wd:Q10841764 ;
        wdt:P54 ?sportTeam .
# ?sportTeam ?p ?parentC ;
            wdt:P31 wd:Q10497835 . 

OPTIONAL{?sportTeam <http://schema.org/name> ?tName .}
OPTIONAL{?parentC <http://schema.org/name> ?cName .}

FILTER((?p = wdt:P127) OR (?p = wdt:749)) ##parent or owned
} 
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('sportTeam', 'http://www.wikidata.org/entity/Q173663'), ('tName', 'Red Bull Racing'), ('parentC', 'http://www.wikidata.org/entity/Q698639'), ('cName', 'Red Bull GmbH')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q171337'), ('tName', 'Williams Grand Prix Engineering'), ('parentC', 'http://www.wikidata.org/entity/Q98714466'), ('cName', 'Dorilton Capital')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q98930155'), ('tName', 'Alpine F1 Team'), ('parentC', 'http://www.wikidata.org/entity/Q6686'), ('cName', 'Renault')]
# 3

# %% [markdown]
# Fixing: Only the team. Discarding the person connection.

# %%
queryString = """
SELECT DISTINCT  ?parentC ?cName
WHERE { 

# ?sportTeam ?p ?parentC ;
            wdt:P31 wd:Q10497835 . 

OPTIONAL{?sportTeam <http://schema.org/name> ?tName .}
OPTIONAL{?parentC <http://schema.org/name> ?cName .}

FILTER(?p=wdt:P361)
} 
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('parentC', 'http://www.wikidata.org/entity/Q26921'), ('cName', 'Alfa Romeo')]
# [('parentC', 'http://www.wikidata.org/entity/Q65961126'), ('cName', 'Honda in Formula One')]
# [('parentC', 'http://www.wikidata.org/entity/Q35982'), ('cName', 'Matra')]
# [('parentC', 'http://www.wikidata.org/entity/Q65962777'), ('cName', 'Toyota in Formula One')]
# [('parentC', 'http://www.wikidata.org/entity/Q64506339'), ('cName', 'Sauber Motorsport')]
# [('parentC', 'http://www.wikidata.org/entity/Q65960697'), ('cName', 'Alfa Romeo in Formula One')]
# [('parentC', 'http://www.wikidata.org/entity/Q25412278'), ('cName', 'Lotus in Formula One')]
# 7

# %% [markdown]
# Exploring Lewis Hamilton Q9673

# %%
queryString = """
SELECT DISTINCT ?p ?pName ?obj ?objName
WHERE { 

wd:Q9673 ?p ?obj . 

OPTIONAL{?p <http://schema.org/name> ?pName .}
OPTIONAL{?obj <http://schema.org/name> ?objName .}

} 
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P1050'), ('pName', 'medical condition'), ('obj', 'http://www.wikidata.org/entity/Q84263196'), ('objName', 'COVID-19')]
# [('p', 'http://www.wikidata.org/prop/direct/P106'), ('pName', 'occupation'), ('obj', 'http://www.wikidata.org/entity/Q10349745'), ('objName', 'racing automobile driver')]
# [('p', 'http://www.wikidata.org/prop/direct/P106'), ('pName', 'occupation'), ('obj', 'http://www.wikidata.org/entity/Q10841764'), ('objName', 'Formula One driver')]
# [('p', 'http://www.wikidata.org/prop/direct/P1343'), ('pName', 'described by source'), ('obj', 'http://www.wikidata.org/entity/Q67311526'), ('objName', 'Obalky knih.cz')]
# [('p', 'http://www.wikidata.org/prop/direct/P1344'), ('pName', 'participant in'), ('obj', 'http://www.wikidata.org/entity/Q918187'), ('objName', 'British Formula Three Championship')]
# [('p', 'http://www.wikidata.org/prop/direct/P1344'), ('pName', 'participant in'), ('obj', 'http://www.wikidata.org/entity/Q962025'), ('objName', 'Formula Renault Eurocup')]
# [('p', 'http://www.wikidata.org/prop/direct/P1344'), ('pName', 'participant in'), ('obj', 'http://www.wikidata.org/entity/Q3114120'), ('objName', '2003 Macau Grand Prix')]
# [('p', 'http://www.wikidata.org/prop/direct/P1344'), ('pName', 'participant in'), ('obj', 'http://www.wikidata.org/entity/Q2626435'), ('objName', 'British Formula Renault Championship')]
# [('p', 'http://www.wikidata.org/prop/direct/P1344'), ('pName', 'participant in'), ('obj', 'http://www.wikidata.org/entity/Q3114121'), ('objName', '2004 Macau Grand Prix')]
# [('p', 'http://www.wikidata.org/prop/direct/P1344'), ('pName', 'participant in'), ('obj', 'http://www.wikidata.org/entity/Q4603030'), ('objName', '2004 Masters of Formula 3')]
# [('p', 'http://www.wikidata.org/prop/direct/P140'), ('pName', 'religion'), ('obj', 'http://www.wikidata.org/entity/Q1841'), ('objName', 'Catholicism')]
# [('p', 'http://www.wikidata.org/prop/direct/P1411'), ('pName', 'nominated for'), ('obj', 'http://www.wikidata.org/entity/Q2267946'), ('objName', 'BBC Sports Personality of the Year Award')]
# [('p', 'http://www.wikidata.org/prop/direct/P1411'), ('pName', 'nominated for'), ('obj', 'http://www.wikidata.org/entity/Q680221'), ('objName', 'Laureus World Sports Award for Breakthrough of the Year')]
# [('p', 'http://www.wikidata.org/prop/direct/P1411'), ('pName', 'nominated for'), ('obj', 'http://www.wikidata.org/entity/Q1808301'), ('objName', 'Laureus World Sports Award for Sportsman of the Year')]
# [('p', 'http://www.wikidata.org/prop/direct/P1411'), ('pName', 'nominated for'), ('obj', 'http://www.wikidata.org/entity/Q4896630'), ('objName', 'Best Driver ESPY Award')]
# [('p', 'http://www.wikidata.org/prop/direct/P1412'), ('pName', 'languages spoken, written or signed'), ('obj', 'http://www.wikidata.org/entity/Q1860'), ('objName', 'English')]
# [('p', 'http://www.wikidata.org/prop/direct/P1576'), ('pName', 'lifestyle'), ('obj', 'http://www.wikidata.org/entity/Q181138'), ('objName', 'veganism')]
# [('p', 'http://www.wikidata.org/prop/direct/P166'), ('pName', 'award received'), ('obj', 'http://www.wikidata.org/entity/Q2267946'), ('objName', 'BBC Sports Personality of the Year Award')]
# [('p', 'http://www.wikidata.org/prop/direct/P166'), ('pName', 'award received'), ('obj', 'http://www.wikidata.org/entity/Q680221'), ('objName', 'Laureus World Sports Award for Breakthrough of the Year')]
# [('p', 'http://www.wikidata.org/prop/direct/P166'), ('pName', 'award received'), ('obj', 'http://www.wikidata.org/entity/Q1061233'), ('objName', "L'Équipe Champion of Champions")]
# [('p', 'http://www.wikidata.org/prop/direct/P166'), ('pName', 'award received'), ('obj', 'http://www.wikidata.org/entity/Q12201526'), ('objName', 'Member of the Order of the British Empire')]
# [('p', 'http://www.wikidata.org/prop/direct/P166'), ('pName', 'award received'), ('obj', 'http://www.wikidata.org/entity/Q1808301'), ('objName', 'Laureus World Sports Award for Sportsman of the Year')]
# [('p', 'http://www.wikidata.org/prop/direct/P19'), ('pName', 'place of birth'), ('obj', 'http://www.wikidata.org/entity/Q19795'), ('objName', 'Stevenage')]
# [('p', 'http://www.wikidata.org/prop/direct/P21'), ('pName', 'sex or gender'), ('obj', 'http://www.wikidata.org/entity/Q6581097'), ('objName', 'male')]
# [('p', 'http://www.wikidata.org/prop/direct/P2522'), ('pName', 'victory'), ('obj', 'http://www.wikidata.org/entity/Q69913'), ('objName', '2008 Formula One World Championship')]
# [('p', 'http://www.wikidata.org/prop/direct/P2522'), ('pName', 'victory'), ('obj', 'http://www.wikidata.org/entity/Q14293115'), ('objName', '2015 Formula One World Championship')]
# [('p', 'http://www.wikidata.org/prop/direct/P2522'), ('pName', 'victory'), ('obj', 'http://www.wikidata.org/entity/Q69969'), ('objName', '2014 Formula One World Championship')]
# [('p', 'http://www.wikidata.org/prop/direct/P2522'), ('pName', 'victory'), ('obj', 'http://www.wikidata.org/entity/Q20755615'), ('objName', '2017 Formula One World Championship')]
# [('p', 'http://www.wikidata.org/prop/direct/P2522'), ('pName', 'victory'), ('obj', 'http://www.wikidata.org/entity/Q41173535'), ('objName', '2019 Formula One World Championship')]
# [('p', 'http://www.wikidata.org/prop/direct/P2522'), ('pName', 'victory'), ('obj', 'http://www.wikidata.org/entity/Q23051084'), ('objName', '2018 Formula One World Championship')]
# [('p', 'http://www.wikidata.org/prop/direct/P2522'), ('pName', 'victory'), ('obj', 'http://www.wikidata.org/entity/Q16838900'), ('objName', '2003 Formula Renault UK season')]
# [('p', 'http://www.wikidata.org/prop/direct/P2522'), ('pName', 'victory'), ('obj', 'http://www.wikidata.org/entity/Q24944688'), ('objName', '2004 Bahrain Superprix')]
# [('p', 'http://www.wikidata.org/prop/direct/P2522'), ('pName', 'victory'), ('obj', 'http://www.wikidata.org/entity/Q901211'), ('objName', '2006 GP2 Series season')]
# [('p', 'http://www.wikidata.org/prop/direct/P27'), ('pName', 'country of citizenship'), ('obj', 'http://www.wikidata.org/entity/Q145'), ('objName', 'United Kingdom')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q5'), ('objName', 'human')]
# [('p', 'http://www.wikidata.org/prop/direct/P451'), ('pName', 'unmarried partner'), ('obj', 'http://www.wikidata.org/entity/Q167696'), ('objName', 'Nicole Scherzinger')]
# [('p', 'http://www.wikidata.org/prop/direct/P54'), ('pName', 'member of sports team'), ('obj', 'http://www.wikidata.org/entity/Q172030'), ('objName', 'McLaren')]
# [('p', 'http://www.wikidata.org/prop/direct/P54'), ('pName', 'member of sports team'), ('obj', 'http://www.wikidata.org/entity/Q172721'), ('objName', 'Mercedes')]
# [('p', 'http://www.wikidata.org/prop/direct/P551'), ('pName', 'residence'), ('obj', 'http://www.wikidata.org/entity/Q235'), ('objName', 'Monaco')]
# [('p', 'http://www.wikidata.org/prop/direct/P551'), ('pName', 'residence'), ('obj', 'http://www.wikidata.org/entity/Q39'), ('objName', 'Switzerland')]
# [('p', 'http://www.wikidata.org/prop/direct/P641'), ('pName', 'sport'), ('obj', 'http://www.wikidata.org/entity/Q2705092'), ('objName', 'Formula One racing')]
# [('p', 'http://www.wikidata.org/prop/direct/P641'), ('pName', 'sport'), ('obj', 'http://www.wikidata.org/entity/Q5386'), ('objName', 'auto racing')]
# [('p', 'http://www.wikidata.org/prop/direct/P641'), ('pName', 'sport'), ('obj', 'http://www.wikidata.org/entity/Q192420'), ('objName', 'kart racing')]
# [('p', 'http://www.wikidata.org/prop/direct/P69'), ('pName', 'educated at'), ('obj', 'http://www.wikidata.org/entity/Q7743376'), ('objName', 'The John Henry Newman School')]
# [('p', 'http://www.wikidata.org/prop/direct/P734'), ('pName', 'family name'), ('obj', 'http://www.wikidata.org/entity/Q21450552'), ('objName', 'Hamilton')]
# [('p', 'http://www.wikidata.org/prop/direct/P735'), ('pName', 'given name'), ('obj', 'http://www.wikidata.org/entity/Q768196'), ('objName', 'Lewis')]
# [('p', 'http://www.wikidata.org/prop/direct/P735'), ('pName', 'given name'), ('obj', 'http://www.wikidata.org/entity/Q2529610'), ('objName', 'Carl')]
# [('p', 'http://www.wikidata.org/prop/direct/P8852'), ('pName', 'facial hair'), ('obj', 'http://www.wikidata.org/entity/Q3504747'), ('objName', 'chinstrap beard')]
# [('p', 'http://www.wikidata.org/prop/direct/P910'), ('pName', "topic's main category"), ('obj', 'http://www.wikidata.org/entity/Q86325061'), ('objName', 'Category:Lewis Hamilton')]
# [('p', 'http://www.wikidata.org/prop/direct/P1006'), ('pName', 'Nationale Thesaurus voor Auteurs ID'), ('obj', '318146843')]
# [('p', 'http://www.wikidata.org/prop/direct/P109'), ('pName', 'signature'), ('obj', 'http://commons.wikimedia.org/wiki/Special:FilePath/Signature%20de%20Lewis%20Hamilton%20png.png')]
# [('p', 'http://www.wikidata.org/prop/direct/P1263'), ('pName', 'NNDB people ID'), ('obj', '884/000163395')]
# [('p', 'http://www.wikidata.org/prop/direct/P1280'), ('pName', 'CONOR.SI ID'), ('obj', '133786467')]
# [('p', 'http://www.wikidata.org/prop/direct/P1285'), ('pName', 'Munzinger Sport number'), ('obj', '01000007207')]
# [('p', 'http://www.wikidata.org/prop/direct/P1296'), ('pName', 'Gran Enciclopèdia Catalana ID'), ('obj', '0283564')]
# [('p', 'http://www.wikidata.org/prop/direct/P1417'), ('pName', 'Encyclopædia Britannica Online ID'), ('obj', 'biography/Lewis-Hamilton')]
# [('p', 'http://www.wikidata.org/prop/direct/P1477'), ('pName', 'birth name'), ('obj', 'Lewis Carl Davidson Hamilton')]
# [('p', 'http://www.wikidata.org/prop/direct/P1695'), ('pName', 'NLP ID (unique)'), ('obj', 'A38351584')]
# [('p', 'http://www.wikidata.org/prop/direct/P1741'), ('pName', 'GTAA ID'), ('obj', '209650')]
# [('p', 'http://www.wikidata.org/prop/direct/P18'), ('pName', 'image'), ('obj', 'http://commons.wikimedia.org/wiki/Special:FilePath/Lewis%20Hamilton%202016%20Malaysia%202.jpg')]
# [('p', 'http://www.wikidata.org/prop/direct/P1816'), ('pName', 'National Portrait Gallery (London) person ID'), ('obj', 'mp93203')]
# [('p', 'http://www.wikidata.org/prop/direct/P1819'), ('pName', 'genealogics.org person ID'), ('obj', 'I00751381')]
# [('p', 'http://www.wikidata.org/prop/direct/P2002'), ('pName', 'Twitter username'), ('obj', 'LewisHamilton')]
# [('p', 'http://www.wikidata.org/prop/direct/P2003'), ('pName', 'Instagram username'), ('obj', 'lewishamilton')]
# [('p', 'http://www.wikidata.org/prop/direct/P2013'), ('pName', 'Facebook ID'), ('obj', 'LewisHamilton')]
# [('p', 'http://www.wikidata.org/prop/direct/P2048'), ('pName', 'height'), ('obj', '174')]
# [('p', 'http://www.wikidata.org/prop/direct/P2067'), ('pName', 'mass'), ('obj', '68')]
# [('p', 'http://www.wikidata.org/prop/direct/P213'), ('pName', 'ISNI'), ('obj', '0000 0000 7849 2376')]
# [('p', 'http://www.wikidata.org/prop/direct/P214'), ('pName', 'VIAF ID'), ('obj', '27390301')]
# [('p', 'http://www.wikidata.org/prop/direct/P2163'), ('pName', 'FAST ID'), ('obj', '1914001')]
# [('p', 'http://www.wikidata.org/prop/direct/P227'), ('pName', 'GND ID'), ('obj', '1126044040')]
# [('p', 'http://www.wikidata.org/prop/direct/P2397'), ('pName', 'YouTube channel ID'), ('obj', 'UCHl4MB8UalGLUydbWdBzG1Q')]
# [('p', 'http://www.wikidata.org/prop/direct/P244'), ('pName', 'Library of Congress authority ID'), ('obj', 'no2008012823')]
# [('p', 'http://www.wikidata.org/prop/direct/P2605'), ('pName', 'ČSFD person ID'), ('obj', '190299')]
# [('p', 'http://www.wikidata.org/prop/direct/P268'), ('pName', 'Bibliothèque nationale de France ID'), ('obj', '156139787')]
# [('p', 'http://www.wikidata.org/prop/direct/P3048'), ('pName', 'racing-reference.info driver ID'), ('obj', 'Lewis_Hamilton')]
# [('p', 'http://www.wikidata.org/prop/direct/P3106'), ('pName', 'Guardian topic ID'), ('obj', 'sport/lewis-hamilton')]
# [('p', 'http://www.wikidata.org/prop/direct/P3219'), ('pName', 'Encyclopædia Universalis ID'), ('obj', 'lewis-hamilton')]
# [('p', 'http://www.wikidata.org/prop/direct/P3222'), ('pName', 'NE.se ID'), ('obj', 'lewis-hamilton')]
# [('p', 'http://www.wikidata.org/prop/direct/P3365'), ('pName', 'Treccani ID'), ('obj', 'lewis-carl-davidson-hamilton')]
# [('p', 'http://www.wikidata.org/prop/direct/P3388'), ('pName', 'LittleSis people ID'), ('obj', '264115')]
# [('p', 'http://www.wikidata.org/prop/direct/P3417'), ('pName', 'Quora topic ID'), ('obj', 'Lewis-Hamilton-F1-driver')]
# [('p', 'http://www.wikidata.org/prop/direct/P3427'), ('pName', 'AS.com athlete ID'), ('obj', 'lewis_hamilton/24341')]
# [('p', 'http://www.wikidata.org/prop/direct/P345'), ('pName', 'IMDb ID'), ('obj', 'nm2619894')]
# [('p', 'http://www.wikidata.org/prop/direct/P349'), ('pName', 'National Diet Library ID'), ('obj', '01141897')]
# [('p', 'http://www.wikidata.org/prop/direct/P3509'), ('pName', 'Dagens Nyheter topic ID'), ('obj', 'lewis-hamilton')]
# [('p', 'http://www.wikidata.org/prop/direct/P3684'), ('pName', 'Driver Database driver ID'), ('obj', 'lewis-hamilton')]
# [('p', 'http://www.wikidata.org/prop/direct/P373'), ('pName', 'Commons category'), ('obj', 'Lewis Hamilton')]
# [('p', 'http://www.wikidata.org/prop/direct/P4342'), ('pName', 'Store norske leksikon ID'), ('obj', 'Lewis_Hamilton')]
# [('p', 'http://www.wikidata.org/prop/direct/P4527'), ('pName', 'UK Parliament thesaurus ID'), ('obj', '473777')]
# [('p', 'http://www.wikidata.org/prop/direct/P4789'), ('pName', "Who's Who UK ID"), ('obj', 'U264761')]
# [('p', 'http://www.wikidata.org/prop/direct/P4985'), ('pName', 'TMDb person ID'), ('obj', '216294')]
# [('p', 'http://www.wikidata.org/prop/direct/P5019'), ('pName', 'Brockhaus Enzyklopädie online ID'), ('obj', 'hamilton-lewis')]
# [('p', 'http://www.wikidata.org/prop/direct/P5421'), ('pName', 'Trading Card Database person ID'), ('obj', '72192')]
# [('p', 'http://www.wikidata.org/prop/direct/P5617'), ('pName', 'Evene ID'), ('obj', 'lewis-hamilton-38514')]
# [('p', 'http://www.wikidata.org/prop/direct/P569'), ('pName', 'date of birth'), ('obj', '1985-01-07T00:00:00Z')]
# [('p', 'http://www.wikidata.org/prop/direct/P6058'), ('pName', 'Larousse ID'), ('obj', 'personnage/wd/184009')]
# [('p', 'http://www.wikidata.org/prop/direct/P646'), ('pName', 'Freebase ID'), ('obj', '/m/031_jy')]
# [('p', 'http://www.wikidata.org/prop/direct/P6706'), ('pName', 'De Agostini ID'), ('obj', 'Hamilton,+Lewis')]
# [('p', 'http://www.wikidata.org/prop/direct/P6723'), ('pName', 'BlackPast.org ID'), ('obj', 'global-african-history/hamilton-lewis-1985')]
# [('p', 'http://www.wikidata.org/prop/direct/P691'), ('pName', 'NKCR AUT ID'), ('obj', 'js20070824004')]
# [('p', 'http://www.wikidata.org/prop/direct/P7293'), ('pName', 'PLWABN ID'), ('obj', '9810560794305606')]
# [('p', 'http://www.wikidata.org/prop/direct/P7666'), ('pName', 'Visuotinė lietuvių enciklopedija ID'), ('obj', 'lewis-hamilton')]
# [('p', 'http://www.wikidata.org/prop/direct/P7818'), ('pName', 'French Vikidia ID'), ('obj', 'Lewis_Hamilton')]
# [('p', 'http://www.wikidata.org/prop/direct/P7859'), ('pName', 'WorldCat Identities ID'), ('obj', 'lccn-no2008012823')]
# [('p', 'http://www.wikidata.org/prop/direct/P8125'), ('pName', 'Fandango person ID'), ('obj', '269346')]
# [('p', 'http://www.wikidata.org/prop/direct/P8140'), ('pName', 'motorsportstats.com driver ID'), ('obj', 'lewis-hamilton')]
# [('p', 'http://www.wikidata.org/prop/direct/P8349'), ('pName', 'Proleksis enciklopedija ID'), ('obj', '152086')]
# [('p', 'http://www.wikidata.org/prop/direct/P856'), ('pName', 'official website'), ('obj', 'https://www.lewishamilton.com/')]
# [('p', 'http://www.wikidata.org/prop/direct/P8672'), ('pName', 'Twitter topic ID'), ('obj', '809514988247232512')]
# [('p', 'http://www.wikidata.org/prop/direct/P8687'), ('pName', 'social media followers'), ('obj', '6169930')]
# [('p', 'http://www.wikidata.org/prop/direct/P935'), ('pName', 'Commons gallery'), ('obj', 'Lewis Hamilton')]
# [('p', 'http://www.wikidata.org/prop/direct/P9368'), ('pName', 'CNA topic ID'), ('obj', 'lewis-hamilton')]
# [('p', 'http://www.wikidata.org/prop/direct/P2984'), ('pName', 'Snapchat username'), ('obj', 'lewishamilton')]
# [('p', 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), ('obj', 'http://wikiba.se/ontology#Item')]
# [('p', 'http://www.wikidata.org/prop/direct-normalized/P1006'), ('obj', 'http://data.bibliotheken.nl/id/thes/p318146843')]
# [('p', 'http://www.wikidata.org/prop/direct-normalized/P1741'), ('obj', 'http://data.beeldengeluid.nl/gtaa/209650')]
# [('p', 'http://www.wikidata.org/prop/direct-normalized/P214'), ('obj', 'http://viaf.org/viaf/27390301')]
# [('p', 'http://www.wikidata.org/prop/direct-normalized/P2163'), ('obj', 'http://id.worldcat.org/fast/1914001')]
# [('p', 'http://www.wikidata.org/prop/direct-normalized/P227'), ('obj', 'https://d-nb.info/gnd/1126044040')]
# [('p', 'http://www.wikidata.org/prop/direct-normalized/P244'), ('obj', 'https://id.loc.gov/authorities/names/no2008012823')]
# [('p', 'http://www.wikidata.org/prop/direct-normalized/P268'), ('obj', 'http://data.bnf.fr/ark:/12148/cb156139787#about')]
# [('p', 'http://www.wikidata.org/prop/direct-normalized/P349'), ('obj', 'http://id.ndl.go.jp/auth/ndlna/01141897')]
# [('p', 'http://www.wikidata.org/prop/direct-normalized/P646'), ('obj', 'http://g.co/kg/m/031_jy')]
# [('p', 'http://schema.org/name'), ('obj', 'Lewis Hamilton')]
# 125

# %% [markdown]
# Looking into <br>
# Q172030 McLaren <br>
# Q172721 Mercedes

# %%
queryString = """
SELECT DISTINCT ?p ?pName ?obj ?objName
WHERE { 

wd:Q172030 ?p ?obj . 

OPTIONAL{?p <http://schema.org/name> ?pName .}
OPTIONAL{?obj <http://schema.org/name> ?objName .}

} 
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P112'), ('pName', 'founded by'), ('obj', 'http://www.wikidata.org/entity/Q173081'), ('objName', 'Bruce McLaren')]
# [('p', 'http://www.wikidata.org/prop/direct/P159'), ('pName', 'headquarters location'), ('obj', 'http://www.wikidata.org/entity/Q646225'), ('objName', 'Woking')]
# [('p', 'http://www.wikidata.org/prop/direct/P17'), ('pName', 'country'), ('obj', 'http://www.wikidata.org/entity/Q145'), ('objName', 'United Kingdom')]
# [('p', 'http://www.wikidata.org/prop/direct/P1889'), ('pName', 'different from'), ('obj', 'http://www.wikidata.org/entity/Q298225'), ('objName', 'McLaren')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q21748148'), ('objName', 'Formula One constructor')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q10497835'), ('objName', 'Formula One team')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q20074337'), ('objName', 'auto racing team')]
# [('p', 'http://www.wikidata.org/prop/direct/P641'), ('pName', 'sport'), ('obj', 'http://www.wikidata.org/entity/Q1968'), ('objName', 'Formula One')]
# [('p', 'http://www.wikidata.org/prop/direct/P749'), ('pName', 'parent organization'), ('obj', 'http://www.wikidata.org/entity/Q173146'), ('objName', 'McLaren Technology Group')]
# [('p', 'http://www.wikidata.org/prop/direct/P910'), ('pName', "topic's main category"), ('obj', 'http://www.wikidata.org/entity/Q13331820'), ('objName', 'Category:McLaren (racing team)')]
# [('p', 'http://www.wikidata.org/prop/direct/P1448'), ('pName', 'official name'), ('obj', 'West McLaren Mercedes')]
# [('p', 'http://www.wikidata.org/prop/direct/P1448'), ('pName', 'official name'), ('obj', 'Marlboro McLaren International')]
# [('p', 'http://www.wikidata.org/prop/direct/P1448'), ('pName', 'official name'), ('obj', 'Vodafone McLaren Mercedes')]
# [('p', 'http://www.wikidata.org/prop/direct/P18'), ('pName', 'image'), ('obj', 'http://commons.wikimedia.org/wiki/Special:FilePath/Sergio%20Perez%202013%20Malaysia%20FP1.jpg')]
# [('p', 'http://www.wikidata.org/prop/direct/P2002'), ('pName', 'Twitter username'), ('obj', 'McLarenF1')]
# [('p', 'http://www.wikidata.org/prop/direct/P2003'), ('pName', 'Instagram username'), ('obj', 'mclaren')]
# [('p', 'http://www.wikidata.org/prop/direct/P2013'), ('pName', 'Facebook ID'), ('obj', 'McLaren.Racing')]
# [('p', 'http://www.wikidata.org/prop/direct/P227'), ('pName', 'GND ID'), ('obj', '4548908-7')]
# [('p', 'http://www.wikidata.org/prop/direct/P2397'), ('pName', 'YouTube channel ID'), ('obj', 'UC8dxVgZl9u5HeCOXnosCtuQ')]
# [('p', 'http://www.wikidata.org/prop/direct/P2427'), ('pName', 'GRID ID'), ('obj', 'grid.451098.1')]
# [('p', 'http://www.wikidata.org/prop/direct/P3417'), ('pName', 'Quora topic ID'), ('obj', 'McLaren-F1')]
# [('p', 'http://www.wikidata.org/prop/direct/P3417'), ('pName', 'Quora topic ID'), ('obj', 'McLaren-car-company')]
# [('p', 'http://www.wikidata.org/prop/direct/P3608'), ('pName', 'EU VAT number'), ('obj', 'GB529057535')]
# [('p', 'http://www.wikidata.org/prop/direct/P373'), ('pName', 'Commons category'), ('obj', 'McLaren (racing team)')]
# [('p', 'http://www.wikidata.org/prop/direct/P571'), ('pName', 'inception'), ('obj', '1963-01-01T00:00:00Z')]
# [('p', 'http://www.wikidata.org/prop/direct/P5785'), ('pName', 'EU Research participant ID'), ('obj', '952034728')]
# [('p', 'http://www.wikidata.org/prop/direct/P6363'), ('pName', 'WordLift URL'), ('obj', 'http://data.thenextweb.com/tnw/entity/mclaren')]
# [('p', 'http://www.wikidata.org/prop/direct/P646'), ('pName', 'Freebase ID'), ('obj', '/m/058q_')]
# [('p', 'http://www.wikidata.org/prop/direct/P6782'), ('pName', 'ROR ID'), ('obj', '023h32w18')]
# [('p', 'http://www.wikidata.org/prop/direct/P856'), ('pName', 'official website'), ('obj', 'https://www.mclaren.com/racing')]
# [('p', 'http://www.wikidata.org/prop/direct/P8672'), ('pName', 'Twitter topic ID'), ('obj', '854719107362467840')]
# [('p', 'http://www.wikidata.org/prop/direct/P8687'), ('pName', 'social media followers'), ('obj', '2207162')]
# [('p', 'http://www.wikidata.org/prop/direct/P8687'), ('pName', 'social media followers'), ('obj', '681000')]
# [('p', 'http://www.wikidata.org/prop/direct/P935'), ('pName', 'Commons gallery'), ('obj', 'McLaren')]
# [('p', 'http://www.wikidata.org/prop/direct/P8178'), ('pName', 'motorsportstats.com team ID'), ('obj', 'mclaren')]
# [('p', 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), ('obj', 'http://wikiba.se/ontology#Item')]
# [('p', 'http://www.wikidata.org/prop/direct-normalized/P227'), ('obj', 'https://d-nb.info/gnd/4548908-7')]
# [('p', 'http://www.wikidata.org/prop/direct-normalized/P646'), ('obj', 'http://g.co/kg/m/058q_')]
# [('p', 'http://schema.org/name'), ('obj', 'McLaren')]
# 39

# %%
queryString = """
SELECT DISTINCT ?p ?pName ?obj ?objName
WHERE { 

wd:Q172721 ?p ?obj . 

OPTIONAL{?p <http://schema.org/name> ?pName .}
OPTIONAL{?obj <http://schema.org/name> ?objName .}

} 
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P1269'), ('pName', 'facet of'), ('obj', 'http://www.wikidata.org/entity/Q65954812'), ('objName', 'Mercedes-Benz in Formula One')]
# [('p', 'http://www.wikidata.org/prop/direct/P17'), ('pName', 'country'), ('obj', 'http://www.wikidata.org/entity/Q145'), ('objName', 'United Kingdom')]
# [('p', 'http://www.wikidata.org/prop/direct/P1889'), ('pName', 'different from'), ('obj', 'http://www.wikidata.org/entity/Q65954812'), ('objName', 'Mercedes-Benz in Formula One')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q21748148'), ('objName', 'Formula One constructor')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q10497835'), ('objName', 'Formula One team')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q20074337'), ('objName', 'auto racing team')]
# [('p', 'http://www.wikidata.org/prop/direct/P641'), ('pName', 'sport'), ('obj', 'http://www.wikidata.org/entity/Q1968'), ('objName', 'Formula One')]
# [('p', 'http://www.wikidata.org/prop/direct/P910'), ('pName', "topic's main category"), ('obj', 'http://www.wikidata.org/entity/Q13331991'), ('objName', 'Category:Mercedes Grand Prix')]
# [('p', 'http://www.wikidata.org/prop/direct/P154'), ('pName', 'logo image'), ('obj', 'http://commons.wikimedia.org/wiki/Special:FilePath/Mercedes%20AMG%20Petronas%20F1%20Logo.svg')]
# [('p', 'http://www.wikidata.org/prop/direct/P154'), ('pName', 'logo image'), ('obj', 'http://commons.wikimedia.org/wiki/Special:FilePath/Logo%20Mercedes%20GP%20Petronas%202011.svg')]
# [('p', 'http://www.wikidata.org/prop/direct/P18'), ('pName', 'image'), ('obj', 'http://commons.wikimedia.org/wiki/Special:FilePath/Mercedes%20duo%202013%20Malaysia.jpg')]
# [('p', 'http://www.wikidata.org/prop/direct/P2002'), ('pName', 'Twitter username'), ('obj', 'MERCEDESAMGF1')]
# [('p', 'http://www.wikidata.org/prop/direct/P2003'), ('pName', 'Instagram username'), ('obj', 'mercedesamgf1')]
# [('p', 'http://www.wikidata.org/prop/direct/P2013'), ('pName', 'Facebook ID'), ('obj', 'MercedesAMGF1')]
# [('p', 'http://www.wikidata.org/prop/direct/P2397'), ('pName', 'YouTube channel ID'), ('obj', 'UC7_VGkwCoKfqh1eZEkzey3A')]
# [('p', 'http://www.wikidata.org/prop/direct/P3417'), ('pName', 'Quora topic ID'), ('obj', 'Mercedes-GP')]
# [('p', 'http://www.wikidata.org/prop/direct/P4264'), ('pName', 'LinkedIn company ID'), ('obj', 'mercedes-amg-petronas-formula-one-team')]
# [('p', 'http://www.wikidata.org/prop/direct/P571'), ('pName', 'inception'), ('obj', '2009-01-01T00:00:00Z')]
# [('p', 'http://www.wikidata.org/prop/direct/P646'), ('pName', 'Freebase ID'), ('obj', '/m/09glm89')]
# [('p', 'http://www.wikidata.org/prop/direct/P856'), ('pName', 'official website'), ('obj', 'https://www.mercedesamgf1.com')]
# [('p', 'http://www.wikidata.org/prop/direct/P8672'), ('pName', 'Twitter topic ID'), ('obj', '854709695772217344')]
# [('p', 'http://www.wikidata.org/prop/direct/P8687'), ('pName', 'social media followers'), ('obj', '773000')]
# [('p', 'http://www.wikidata.org/prop/direct/P8687'), ('pName', 'social media followers'), ('obj', '2916627')]
# [('p', 'http://www.wikidata.org/prop/direct/P8178'), ('pName', 'motorsportstats.com team ID'), ('obj', 'mercedes-2')]
# [('p', 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), ('obj', 'http://wikiba.se/ontology#Item')]
# [('p', 'http://www.wikidata.org/prop/direct-normalized/P646'), ('obj', 'http://g.co/kg/m/09glm89')]
# [('p', 'http://schema.org/name'), ('obj', 'Mercedes')]
# 27

# %% [markdown]
# Trying to modify the previous query for the parent company, for the second question.

# %% [markdown]
# **Answer 2**
#
# I have to use multiple choice for the key property: P749 "parent organization", P127 "owned by" or P361 "part of"

# %%
queryString = """
SELECT ?sportTeam ?tName ?parentC ?cName
WHERE { 

# ?sportTeam ?p ?parentC ;
            wdt:P31 wd:Q10497835 . 

OPTIONAL{?sportTeam <http://schema.org/name> ?tName .}
OPTIONAL{?parentC <http://schema.org/name> ?cName .}

FILTER (?p = wdt:P749 OR ?p = wdt:P127 OR ?p = wdt:P361)
} 
ORDER BY ASC (?tName)
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('sportTeam', 'http://www.wikidata.org/entity/Q622489'), ('tName', 'Alfa Romeo'), ('parentC', 'http://www.wikidata.org/entity/Q26921'), ('cName', 'Alfa Romeo')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q84562599'), ('tName', 'Alfa Romeo F1 team (2019)'), ('parentC', 'http://www.wikidata.org/entity/Q65960697'), ('cName', 'Alfa Romeo in Formula One')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q61467970'), ('tName', 'Alfa Romeo F1 team (1950-51)'), ('parentC', 'http://www.wikidata.org/entity/Q65960697'), ('cName', 'Alfa Romeo in Formula One')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q98930155'), ('tName', 'Alpine F1 Team'), ('parentC', 'http://www.wikidata.org/entity/Q6686'), ('cName', 'Renault')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q2704273'), ('tName', 'Aston Martin F1 Team'), ('parentC', 'http://www.wikidata.org/entity/Q27074'), ('cName', 'Aston Martin Lagonda')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q173314'), ('tName', 'Enzo Coloni Racing Car Systems'), ('parentC', 'http://www.wikidata.org/entity/Q1631454'), ('cName', 'Scuderia Coloni')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q844092'), ('tName', 'Equipe Matra Sports'), ('parentC', 'http://www.wikidata.org/entity/Q35982'), ('cName', 'Matra')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q171342'), ('tName', 'Honda'), ('parentC', 'http://www.wikidata.org/entity/Q65961126'), ('cName', 'Honda in Formula One')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q173018'), ('tName', 'Lotus F1'), ('parentC', 'http://www.wikidata.org/entity/Q25412278'), ('cName', 'Lotus in Formula One')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q172030'), ('tName', 'McLaren'), ('parentC', 'http://www.wikidata.org/entity/Q173146'), ('cName', 'McLaren Technology Group')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q61979'), ('tName', 'Panasonic Toyota Racing'), ('parentC', 'http://www.wikidata.org/entity/Q65962777'), ('cName', 'Toyota in Formula One')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q173663'), ('tName', 'Red Bull Racing'), ('parentC', 'http://www.wikidata.org/entity/Q698639'), ('cName', 'Red Bull GmbH')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q171335'), ('tName', 'Sauber'), ('parentC', 'http://www.wikidata.org/entity/Q64506339'), ('cName', 'Sauber Motorsport')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q169898'), ('tName', 'Scuderia Ferrari'), ('parentC', 'http://www.wikidata.org/entity/Q27586'), ('cName', 'Ferrari')]
# [('sportTeam', 'http://www.wikidata.org/entity/Q171337'), ('tName', 'Williams Grand Prix Engineering'), ('parentC', 'http://www.wikidata.org/entity/Q98714466'), ('cName', 'Dorilton Capital')]
# 15

# %% [markdown]
# BGP
#
# ```
# ?sportTeam ?p ?parentC ;
#             wdt:P31 wd:Q10497835 .
#
# OPTIONAL{?sportTeam <http://schema.org/name> ?tName .}
# OPTIONAL{?parentC <http://schema.org/name> ?cName .}
#
# FILTER (?p = wdt:P749 OR ?p = wdt:P127 OR ?p = wdt:P361)
#
# ```

# %% [markdown]
# ------

# %% [markdown]
# **How many F1 drivers and F1 teams exist in each country?**

# %%
queryString = """
SELECT COUNT((?person)) AS ?num_drivers COUNT((?sportTeam)) as ?num_teams
WHERE { 

# ?person wdt:P106 wd:Q10841764 ;
        wdt:P54 ?sportTeam ;
        wdt:P27 ?country .
        
# ?sportTeam wdt:P31 wd:Q10497835 ;
            wdt:P17 ?country .

OPTIONAL{?sportTeam <http://schema.org/name> ?tName .}
OPTIONAL{?country <http://schema.org/name> ?cName .}

} 
GROUP BY (?num_drivers) (?num_teams)
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('num_drivers', '37'), ('num_teams', '37')]
# 1

# %% [markdown]
# It is wrong...
#
# I fix it. Here I consider the driver-team connection, but the reults are limited

# %%
queryString = """
SELECT COUNT(?sportTeam) as ?num_teams ?cName
WHERE { 

# ?person wdt:P106 wd:Q10841764 ;
        wdt:P54 ?sportTeam ;
        wdt:P27 ?country .
        
# ?sportTeam wdt:P31 wd:Q10497835 ;
            wdt:P17 ?country .

OPTIONAL{?sportTeam <http://schema.org/name> ?tName .}
OPTIONAL{?country <http://schema.org/name> ?cName .}

} 
GROUP BY (?num_teams) (?cName)
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('num_teams', '1'), ('cName', 'Australia')]
# [('num_teams', '9'), ('cName', 'Italy')]
# [('num_teams', '26'), ('cName', 'United Kingdom')]
# [('num_teams', '1'), ('cName', 'France')]
# 4

# %% [markdown]
# Using only the "team" entity I can retrieve more data.
#
# **Answer 3**
#
# Here I have the number of team in each country

# %%
queryString = """
SELECT (COUNT(DISTINCT (?sportTeam)) as ?num_teams) ?cName
WHERE { 

# ?sportTeam wdt:P31 wd:Q10497835 ;
            wdt:P17 ?country .

OPTIONAL{?sportTeam <http://schema.org/name> ?tName .}
OPTIONAL{?country <http://schema.org/name> ?cName .}

} 
GROUP BY (?num_teams) (?cName)
ORDER BY ASC (?num_teams)
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('num_teams', '1'), ('cName', 'Malaysia')]
# [('num_teams', '1'), ('cName', 'Spain')]
# [('num_teams', '1'), ('cName', 'Australia')]
# [('num_teams', '1'), ('cName', 'Switzerland')]
# [('num_teams', '2'), ('cName', 'Netherlands')]
# [('num_teams', '2'), ('cName', 'Japan')]
# [('num_teams', '2'), ('cName', 'Russia')]
# [('num_teams', '2'), ('cName', 'Germany')]
# [('num_teams', '6'), ('cName', 'France')]
# [('num_teams', '16'), ('cName', 'Italy')]
# [('num_teams', '26'), ('cName', 'United Kingdom')]
# 11

# %%
queryString = """
SELECT (COUNT(DISTINCT (?person)) as ?num_driver) ?cName
WHERE { 


# ?person wdt:P106 wd:Q10841764 ;
        wdt:P54 ?sportTeam ;
        wdt:P27 ?country .
        
# ?sportTeam wdt:P31 wd:Q10497835 ;
            wdt:P17 ?country .

OPTIONAL{?person <http://schema.org/name> ?pName .}
OPTIONAL{?country <http://schema.org/name> ?cName .}

} 
GROUP BY (?num_driver) (?cName)
ORDER BY ASC (?num_driver)
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('num_driver', '1'), ('cName', 'Australia')]
# [('num_driver', '1'), ('cName', 'France')]
# [('num_driver', '6'), ('cName', 'Italy')]
# [('num_driver', '20'), ('cName', 'United Kingdom')]
# 4

# %% [markdown]
# **Answer 3**
#
# Not all paths are preset (ex Lance Stroll query ). I remove the property P54 "member of sport team"
#
# Using only the "driver" entity.
#
# Here I have the number of drivers for each country.

# %%
queryString = """
SELECT (COUNT(DISTINCT (?person)) as ?num_driver) ?cName
WHERE { 

# ?person wdt:P106 wd:Q10841764 ;
        wdt:P27 ?country .
        
OPTIONAL{?person <http://schema.org/name> ?pName .}
OPTIONAL{?country <http://schema.org/name> ?cName .}

} 
GROUP BY (?num_driver) (?cName)
ORDER BY ASC (?num_driver)
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('num_driver', '1'), ('cName', 'Wales')]
# [('num_driver', '1'), ('cName', 'Georgia')]
# [('num_driver', '1'), ('cName', 'Japan')]
# [('num_driver', '1'), ('cName', 'Romania')]
# [('num_driver', '1'), ('cName', 'Northern Ireland')]
# [('num_driver', '1'), ('cName', 'Monaco')]
# [('num_driver', '1'), ('cName', 'New Zealand')]
# [('num_driver', '1'), ('cName', 'West Germany')]
# [('num_driver', '1'), ('cName', 'Venezuela')]
# [('num_driver', '2'), ('cName', 'Poland')]
# [('num_driver', '2'), ('cName', 'Denmark')]
# [('num_driver', '2'), ('cName', 'Thailand')]
# [('num_driver', '2'), ('cName', 'Switzerland')]
# [('num_driver', '3'), ('cName', 'Australia')]
# [('num_driver', '3'), ('cName', 'German Democratic Republic')]
# [('num_driver', '5'), ('cName', 'Portugal')]
# [('num_driver', '5'), ('cName', 'Mexico')]
# [('num_driver', '6'), ('cName', 'Brazil')]
# [('num_driver', '7'), ('cName', 'Ireland')]
# [('num_driver', '9'), ('cName', 'Kingdom of Italy')]
# [('num_driver', '9'), ('cName', 'Finland')]
# [('num_driver', '14'), ('cName', 'France')]
# [('num_driver', '16'), ('cName', 'Canada')]
# [('num_driver', '16'), ('cName', 'United Kingdom of Great Britain and Ireland')]
# [('num_driver', '17'), ('cName', 'Kingdom of the Netherlands')]
# [('num_driver', '18'), ('cName', 'Spain')]
# [('num_driver', '18'), ('cName', 'Austria')]
# [('num_driver', '19'), ('cName', 'Italy')]
# [('num_driver', '25'), ('cName', 'Argentina')]
# [('num_driver', '27'), ('cName', 'South Africa')]
# [('num_driver', '28'), ('cName', 'Belgium')]
# [('num_driver', '58'), ('cName', 'Germany')]
# [('num_driver', '172'), ('cName', 'United Kingdom')]
# [('num_driver', '245'), ('cName', 'United States of America')]
# 34

# %% [markdown]
# -------------
#
# **4 - Compare the number of F1 drivers to their nationality**

# %% [markdown]
#  4.1 Is there some driver that joined a team in their own country?
#
#  4.2 Which team employed the larger number of drivers?
#
#  4.3 For each country , which are the teams and drivers with the highest number of F1 race participations

# %% [markdown]
# **Answer 4.1**
#
# I print the driver, the team and the country, filtering for the country of the driver to be the same as the one of the sport team

# %%
queryString = """
SELECT (?pName AS ?Name) (?tName1 AS ?Team) (?cName1 AS ?Country)
WHERE { 

# ?person wdt:P106 wd:Q10841764 ;
        wdt:P27 ?country1 ;
        wdt:P54 ?sportTeam1 .
        
     { #sub
         SELECT ?cName ?tName WHERE
     {
             # ?sportTeam wdt:P31 wd:Q10497835 ;
                        wdt:P17 ?country .
            # ?sportTeam <http://schema.org/name> ?tName .
            # ?country <http://schema.org/name> ?cName .
     }
     } #sub


# ?sportTeam1 <http://schema.org/name> ?tName1 .
# ?person <http://schema.org/name> ?pName .
# ?country1 <http://schema.org/name> ?cName1 .

FILTER(?cName=?cName1 AND ?tName = ?tName1)

} 
ORDER BY ASC (?pName)
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('Name', 'Alexander Albon'), ('Team', 'Red Bull Racing'), ('Country', 'United Kingdom')]
# [('Name', 'Antonio Giovinazzi'), ('Team', 'Alfa Romeo'), ('Country', 'Italy')]
# [('Name', 'Arturo Merzario'), ('Team', 'Scuderia Ferrari'), ('Country', 'Italy')]
# [('Name', 'Bruno Giacomelli'), ('Team', 'Alfa Romeo'), ('Country', 'Italy')]
# [('Name', 'Bruno Giacomelli'), ('Team', 'Life Racing Engines'), ('Country', 'Italy')]
# [('Name', 'Chris Irwin'), ('Team', 'Brabham'), ('Country', 'United Kingdom')]
# [('Name', 'Dave Charlton'), ('Team', 'Brabham'), ('Country', 'United Kingdom')]
# [('Name', 'David Coulthard'), ('Team', 'Williams Grand Prix Engineering'), ('Country', 'United Kingdom')]
# [('Name', 'David Coulthard'), ('Team', 'McLaren'), ('Country', 'United Kingdom')]
# [('Name', 'David Coulthard'), ('Team', 'Red Bull Racing'), ('Country', 'United Kingdom')]
# [('Name', 'Enrico Bertaggia'), ('Team', 'Andrea Moda Formula'), ('Country', 'Italy')]
# [('Name', 'Enrico Bertaggia'), ('Team', 'Forti'), ('Country', 'Italy')]
# [('Name', 'Enrico Bertaggia'), ('Team', 'Enzo Coloni Racing Car Systems'), ('Country', 'Italy')]
# [('Name', 'George Russell'), ('Team', 'Williams Grand Prix Engineering'), ('Country', 'United Kingdom')]
# [('Name', 'Graham Hill'), ('Team', 'British Racing Motors'), ('Country', 'United Kingdom')]
# [('Name', 'Graham Hill'), ('Team', 'Brabham'), ('Country', 'United Kingdom')]
# [('Name', 'Jack Brabham'), ('Team', 'Brabham'), ('Country', 'Australia')]
# [('Name', 'Jack Fairman'), ('Team', 'British Racing Motors'), ('Country', 'United Kingdom')]
# [('Name', 'Jackie Oliver'), ('Team', 'McLaren'), ('Country', 'United Kingdom')]
# [('Name', 'Jackie Oliver'), ('Team', 'British Racing Motors'), ('Country', 'United Kingdom')]
# [('Name', 'Jackie Stewart'), ('Team', 'Tyrrell Racing'), ('Country', 'United Kingdom')]
# [('Name', 'Jackie Stewart'), ('Team', 'British Racing Motors'), ('Country', 'United Kingdom')]
# [('Name', 'James Hunt'), ('Team', 'McLaren'), ('Country', 'United Kingdom')]
# [('Name', 'John Surtees'), ('Team', 'British Racing Motors'), ('Country', 'United Kingdom')]
# [('Name', 'Johnny Servoz-Gavin'), ('Team', 'Equipe Matra Sports'), ('Country', 'France')]
# [('Name', 'Lando Norris'), ('Team', 'McLaren'), ('Country', 'United Kingdom')]
# [('Name', 'Les Leston'), ('Team', 'British Racing Motors'), ('Country', 'United Kingdom')]
# [('Name', 'Lewis Hamilton'), ('Team', 'Mercedes'), ('Country', 'United Kingdom')]
# [('Name', 'Lewis Hamilton'), ('Team', 'McLaren'), ('Country', 'United Kingdom')]
# [('Name', 'Mario Andretti'), ('Team', 'Alfa Romeo'), ('Country', 'Italy')]
# [('Name', 'Mike Spence'), ('Team', 'British Racing Motors'), ('Country', 'United Kingdom')]
# [('Name', 'Peter Walker'), ('Team', 'British Racing Motors'), ('Country', 'United Kingdom')]
# [('Name', 'Riccardo Patrese'), ('Team', 'Alfa Romeo'), ('Country', 'Italy')]
# [('Name', 'Richard Attwood'), ('Team', 'British Racing Motors'), ('Country', 'United Kingdom')]
# [('Name', 'Ron Flockhart'), ('Team', 'British Racing Motors'), ('Country', 'United Kingdom')]
# [('Name', 'Roy Salvadori'), ('Team', 'British Racing Motors'), ('Country', 'United Kingdom')]
# [('Name', 'Tony Brooks'), ('Team', 'British Racing Motors'), ('Country', 'United Kingdom')]
# 37

# %% [markdown]
# **Answer 4.2**
#
# Modifying a bit one of the previous queries

# %%
queryString = """
SELECT (COUNT(?person) AS ?num_drivers) (?tName AS ?Team)
WHERE { 

# ?person wdt:P106 wd:Q10841764 ;
        wdt:P54 ?sportTeam .

# ?sportTeam <http://schema.org/name> ?tName .
# ?person <http://schema.org/name> ?pName .

} 
GROUP BY (?num_drivers) (?tName)
ORDER BY DESC (?num_drivers)
LIMIT 1
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('num_drivers', '17'), ('Team', 'Team Lotus')]
# 1

# %% [markdown]
# **4.3**
# Unfortuately I'm not able to answer to this point because in the previous points I did not find the path for the partecipation of a driver to the competitions...

# %%
queryString = """
SELECT ?sportTeam ?tName ?parentC ?cName
WHERE { 

# ?person wdt:P106 wd:Q10841764 .
# ?person wdt:P27 wd:Q183 .

# BGP to retrieve all citizens of Germany (driver tedeschi)

# ?sportTeam wdt:P17 wd:Q183 .
# ?sportTeam wdt:P31 wd:Q10497835 .

# BGP to retrieve all F1 teams of Germany

# ?person wdt:P106 wd:Q10841764 ;
        wdt:P54 ?sportTeam .
# ?sportTeam wdt:P31 wd:Q10497835 . 

OPTIONAL{?sportTeam <http://schema.org/name> ?tName .}
OPTIONAL{?parentC <http://schema.org/name> ?cName .}

FILTER (?p = wdt:P749 OR ?p = wdt:P127 OR ?p = wdt:P361)
} 
ORDER BY ASC (?tName)
"""

print("Results")
run_query(queryString)

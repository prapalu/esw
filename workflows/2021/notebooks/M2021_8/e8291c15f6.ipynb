# %% [markdown]
# # General instructions
#
# The goal of the project is to materialize a set of **exploratory workloads** over a real-world, large-scale,  open-domain KG: [WikiData](https://www.wikidata.org/wiki/Wikidata:Main_Page)
#
# An exploratory workload  is composed by a set of queries, where each query is related to the information obtained previously.
#
# An exploratory workload starts with a usually vague, open ended question, and does not assume the person issuing the workload has a clear understanding of the data contained in the target database or its structure.
#
# Remeber that:
#
# 1. All the queries must run in the python notebook
# 2. You can use classes and properties only if you find them via a SPARQL query that must be present in the notebook
# 3. You do not delete useless queries. Keep everything that is synthatically valid
#
# ```
# ?p <http://schema.org/name> ?name .
# ```
#
#     is the BGP returning a human-readable name of a property or a class in Wikidata.

# %%
## SETUP used later

from SPARQLWrapper import SPARQLWrapper, JSON


prefixString = """
##-e8291c15f6-##
PREFIX wd: <http://www.wikidata.org/entity/> 
PREFIX wdt: <http://www.wikidata.org/prop/direct/> 
PREFIX sc: <http://schema.org/>
"""

# select and construct queries
def run_query(queryString):
    to_run = prefixString + "\n" + queryString

    sparql = SPARQLWrapper("http://a256-gc1-02.srv.aau.dk:5820/sparql")
    sparql.setTimeout(300)
    sparql.setReturnFormat(JSON)
    sparql.setQuery(to_run)

    try :
       results = sparql.query()
       json_results = results.convert()
       if len(json_results['results']['bindings'])==0:
          print("Empty")
          return 0
    
       for bindings in json_results['results']['bindings']:
          print( [ (var, value['value'])  for var, value in bindings.items() ] )

       return len(json_results['results']['bindings'])

    except Exception as e :
        print("The operation failed", e)
    
# ASk queries
def run_ask_query(queryString):
    to_run = prefixString + "\n" + queryString

    sparql = SPARQLWrapper("http://a256-gc1-02.srv.aau.dk:5820/sparql")
    sparql.setTimeout(300)
    sparql.setReturnFormat(JSON)
    sparql.setQuery(to_run)

    try :
        return sparql.query().convert()

    except Exception as e :
        print("The operation failed", e)

# %% [markdown]
# # Book Workflow Series ("Author comparison explorative search")
#
# Consider the following exploratory scenario:
#
#
# >  Investigate Italian and French book authors in terms of awards, books published and copyright types
#
#
#
# ## Useful URIs for the current workflow
# The following are given:
#
# | IRI           | Description   | Role      |
# | -----------   | -----------   |-----------|
# | `wdt:P1647`   | subproperty   | predicate |
# | `wdt:P31`     | instance of   | predicate |
# | `wdt:P279`    | subclass      | predicate |
# | `wdt:P106`    | occupation    | predicate |
# | `wdt:P17`     | country       | predicate |
# | `wdt:P27`     | citizenship   | predicate |
# | `wd:Q36180`   | writer        | node |
# | `wd:Q38`      | Italy         | node |
# | `wd:Q172579`  | Kingdom of Italy        | node |
# | `wd:Q142`     | France        | node |
# | `wd:Q37922`   | Nobel Prize literature        | node |
# | `wd:Q213678`  | Vatican Library        | node |
#
#
# Also consider that
#
# ```
# ?p wdt:P27 wd:Q142
# ```
#
# is the BGP to retrieve all **French citizens**
#
#
# The workload should
#
#
# 1. Identify the BGP for obtaining the Italian and French writers who published a book in the last 50 years
#
# 2. Compare the number of books written by Italian and French writers
#
# 3. Count how many books written by Italian authors are now released with a "public domain" copyright form
#
# 4. How many Literature Nobel awards won authors from Italy and from the Kingdom of Italy?
#
# 5. Are there books from Litarature Nobel Award winners which are not present in the Vatican Library? (if so, who is the author with more books not in the Vatical Library)?

# %%
# start your workflow here

# %%
queryString = """
SELECT COUNT(?p)
WHERE { 
# ?p wdt:P27 wd:Q142 .
} 
"""

print("Results")
run_query(queryString)

# %% [markdown]
# ## Task 1 - Identify the BGP for obtaining the Italian and French writers who published a book in the last 50 years

# %% [markdown]
# #### I start by finding all French and Italian writers

# %%
queryString = """
SELECT DISTINCT ?name WHERE { 

{?writer wdt:P27 wd:Q142;
         wdt:P106 wd:Q36180.
         }
UNION
{?writer wdt:P27 wd:Q38;
         wdt:P106 wd:Q36180.}

# ?writer <http://schema.org/name> ?name .

} limit 100

"""

print("Results")
run_query(queryString)

# %% [markdown]
# #### I inspect their properties

# %%
queryString = """
SELECT DISTINCT ?p ?pname (COUNT(?obj) AS ?count) WHERE { 

{?writer wdt:P27 wd:Q142;
         wdt:P106 wd:Q36180;
         # ?p ?obj.
         }
UNION
{?writer wdt:P27 wd:Q38;
         wdt:P106 wd:Q36180;
         # ?p ?obj.
         }

# ?p <http://schema.org/name> ?pname .

}GROUP BY ?p ?pname
ORDER BY DESC (?count)
LIMIT 100
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P106'), ('pname', 'occupation'), ('count', '53470')]
# [('p', 'http://www.wikidata.org/prop/direct/P27'), ('pname', 'country of citizenship'), ('count', '24226')]
# [('p', 'http://www.wikidata.org/prop/direct/P1412'), ('pname', 'languages spoken, written or signed'), ('count', '22225')]
# [('p', 'http://www.wikidata.org/prop/direct/P735'), ('pname', 'given name'), ('count', '20753')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pname', 'instance of'), ('count', '20680')]
# [('p', 'http://www.wikidata.org/prop/direct/P21'), ('pname', 'sex or gender'), ('count', '20634')]
# [('p', 'http://www.wikidata.org/prop/direct/P569'), ('pname', 'date of birth'), ('count', '20280')]
# [('p', 'http://www.wikidata.org/prop/direct/P214'), ('pname', 'VIAF ID'), ('count', '19026')]
# [('p', 'http://www.wikidata.org/prop/direct/P7859'), ('pname', 'WorldCat Identities ID'), ('count', '18025')]
# [('p', 'http://www.wikidata.org/prop/direct/P19'), ('pname', 'place of birth'), ('count', '17364')]
# [('p', 'http://www.wikidata.org/prop/direct/P213'), ('pname', 'ISNI'), ('count', '17122')]
# [('p', 'http://www.wikidata.org/prop/direct/P268'), ('pname', 'Bibliothèque nationale de France ID'), ('count', '15751')]
# [('p', 'http://www.wikidata.org/prop/direct/P244'), ('pname', 'Library of Congress authority ID'), ('count', '14289')]
# [('p', 'http://www.wikidata.org/prop/direct/P269'), ('pname', 'IdRef ID'), ('count', '14107')]
# [('p', 'http://www.wikidata.org/prop/direct/P734'), ('pname', 'family name'), ('count', '13685')]
# [('p', 'http://www.wikidata.org/prop/direct/P2671'), ('pname', 'Google Knowledge Graph ID'), ('count', '11635')]
# [('p', 'http://www.wikidata.org/prop/direct/P570'), ('pname', 'date of death'), ('count', '11583')]
# [('p', 'http://www.wikidata.org/prop/direct/P166'), ('pname', 'award received'), ('count', '10531')]
# [('p', 'http://www.wikidata.org/prop/direct/P1006'), ('pname', 'Nationale Thesaurus voor Auteurs ID'), ('count', '10255')]
# [('p', 'http://www.wikidata.org/prop/direct/P227'), ('pname', 'GND ID'), ('count', '9466')]
# [('p', 'http://www.wikidata.org/prop/direct/P20'), ('pname', 'place of death'), ('count', '9295')]
# [('p', 'http://www.wikidata.org/prop/direct/P1207'), ('pname', 'NUKAT ID'), ('count', '8805')]
# [('p', 'http://www.wikidata.org/prop/direct/P18'), ('pname', 'image'), ('count', '7738')]
# [('p', 'http://www.wikidata.org/prop/direct/P103'), ('pname', 'native language'), ('count', '6753')]
# [('p', 'http://www.wikidata.org/prop/direct/P3630'), ('pname', 'Babelio author ID'), ('count', '6474')]
# [('p', 'http://www.wikidata.org/prop/direct/P3987'), ('pname', 'SHARE Catalogue author ID'), ('count', '6087')]
# [('p', 'http://www.wikidata.org/prop/direct/P646'), ('pname', 'Freebase ID'), ('count', '5984')]
# [('p', 'http://www.wikidata.org/prop/direct/P2163'), ('pname', 'FAST ID'), ('count', '5865')]
# [('p', 'http://www.wikidata.org/prop/direct/P7293'), ('pname', 'PLWABN ID'), ('count', '5857')]
# [('p', 'http://www.wikidata.org/prop/direct/P373'), ('pname', 'Commons category'), ('count', '5691')]
# [('p', 'http://www.wikidata.org/prop/direct/P691'), ('pname', 'NKCR AUT ID'), ('count', '5623')]
# [('p', 'http://www.wikidata.org/prop/direct/P648'), ('pname', 'Open Library ID'), ('count', '5541')]
# [('p', 'http://www.wikidata.org/prop/direct/P1343'), ('pname', 'described by source'), ('count', '5361')]
# [('p', 'http://www.wikidata.org/prop/direct/P69'), ('pname', 'educated at'), ('count', '5303')]
# [('p', 'http://www.wikidata.org/prop/direct/P950'), ('pname', 'Biblioteca Nacional de España ID'), ('count', '4518')]
# [('p', 'http://www.wikidata.org/prop/direct/P6886'), ('pname', 'writing language'), ('count', '4205')]
# [('p', 'http://www.wikidata.org/prop/direct/P396'), ('pname', 'SBN author ID'), ('count', '3987')]
# [('p', 'http://www.wikidata.org/prop/direct/P108'), ('pname', 'employer'), ('count', '3800')]
# [('p', 'http://www.wikidata.org/prop/direct/P7902'), ('pname', 'Deutsche Biographie (GND) ID'), ('count', '3733')]
# [('p', 'http://www.wikidata.org/prop/direct/P8034'), ('pname', 'Vatican Library VcBA ID'), ('count', '3526')]
# [('p', 'http://www.wikidata.org/prop/direct/P39'), ('pname', 'position held'), ('count', '3260')]
# [('p', 'http://www.wikidata.org/prop/direct/P463'), ('pname', 'member of'), ('count', '2974')]
# [('p', 'http://www.wikidata.org/prop/direct/P3762'), ('pname', 'openMLOL author ID'), ('count', '2972')]
# [('p', 'http://www.wikidata.org/prop/direct/P7763'), ('pname', 'copyright status as a creator'), ('count', '2903')]
# [('p', 'http://www.wikidata.org/prop/direct/P345'), ('pname', 'IMDb ID'), ('count', '2729')]
# [('p', 'http://www.wikidata.org/prop/direct/P1280'), ('pname', 'CONOR.SI ID'), ('count', '2705')]
# [('p', 'http://www.wikidata.org/prop/direct/P1005'), ('pname', 'Portuguese National Library ID'), ('count', '2659')]
# [('p', 'http://www.wikidata.org/prop/direct/P1015'), ('pname', 'NORAF ID'), ('count', '2562')]
# [('p', 'http://www.wikidata.org/prop/direct/P1871'), ('pname', 'CERL Thesaurus ID'), ('count', '2516')]
# [('p', 'http://www.wikidata.org/prop/direct/P1017'), ('pname', 'Vatican Library ID (former scheme)'), ('count', '2428')]
# [('p', 'http://www.wikidata.org/prop/direct/P1315'), ('pname', 'NLA Trove ID'), ('count', '2379')]
# [('p', 'http://www.wikidata.org/prop/direct/P742'), ('pname', 'pseudonym'), ('count', '2256')]
# [('p', 'http://www.wikidata.org/prop/direct/P1977'), ('pname', 'Les Archives du Spectacle Person ID'), ('count', '2192')]
# [('p', 'http://www.wikidata.org/prop/direct/P7865'), ('pname', 'CoBiS author ID'), ('count', '2154')]
# [('p', 'http://www.wikidata.org/prop/direct/P949'), ('pname', 'National Library of Israel ID'), ('count', '2136')]
# [('p', 'http://www.wikidata.org/prop/direct/P800'), ('pname', 'notable work'), ('count', '2108')]
# [('p', 'http://www.wikidata.org/prop/direct/P1273'), ('pname', 'CANTIC ID'), ('count', '1983')]
# [('p', 'http://www.wikidata.org/prop/direct/P409'), ('pname', 'Libraries Australia ID'), ('count', '1942')]
# [('p', 'http://www.wikidata.org/prop/direct/P6379'), ('pname', 'has works in the collection'), ('count', '1896')]
# [('p', 'http://www.wikidata.org/prop/direct/P9058'), ('pname', 'Fichier des personnes décédées ID (matchID)'), ('count', '1891')]
# [('p', 'http://www.wikidata.org/prop/direct/P3065'), ('pname', 'RERO ID'), ('count', '1826')]
# [('p', 'http://www.wikidata.org/prop/direct/P1580'), ('pname', 'University of Barcelona authority ID'), ('count', '1800')]
# [('p', 'http://www.wikidata.org/prop/direct/P3430'), ('pname', 'SNAC ARK ID'), ('count', '1752')]
# [('p', 'http://www.wikidata.org/prop/direct/P906'), ('pname', 'SELIBR ID'), ('count', '1740')]
# [('p', 'http://www.wikidata.org/prop/direct/P5587'), ('pname', 'Libris-URI'), ('count', '1718')]
# [('p', 'http://www.wikidata.org/prop/direct/P26'), ('pname', 'spouse'), ('count', '1709')]
# [('p', 'http://www.wikidata.org/prop/direct/P349'), ('pname', 'National Diet Library ID'), ('count', '1674')]
# [('p', 'http://www.wikidata.org/prop/direct/P40'), ('pname', 'child'), ('count', '1653')]
# [('p', 'http://www.wikidata.org/prop/direct/P3348'), ('pname', 'National Library of Greece ID'), ('count', '1653')]
# [('p', 'http://www.wikidata.org/prop/direct/P119'), ('pname', 'place of burial'), ('count', '1653')]
# [('p', 'http://www.wikidata.org/prop/direct/P5034'), ('pname', 'National Library of Korea ID'), ('count', '1598')]
# [('p', 'http://www.wikidata.org/prop/direct/P4985'), ('pname', 'TMDb person ID'), ('count', '1598')]
# [('p', 'http://www.wikidata.org/prop/direct/P5731'), ('pname', 'Angelicum ID'), ('count', '1586')]
# [('p', 'http://www.wikidata.org/prop/direct/P136'), ('pname', 'genre'), ('count', '1575')]
# [('p', 'http://www.wikidata.org/prop/direct/P856'), ('pname', 'official website'), ('count', '1553')]
# [('p', 'http://www.wikidata.org/prop/direct/P5739'), ('pname', 'Pontificia Università della Santa Croce ID'), ('count', '1529')]
# [('p', 'http://www.wikidata.org/prop/direct/P3373'), ('pname', 'sibling'), ('count', '1477')]
# [('p', 'http://www.wikidata.org/prop/direct/P1695'), ('pname', 'NLP ID (unique)'), ('count', '1466')]
# [('p', 'http://www.wikidata.org/prop/direct/P7704'), ('pname', 'Europeana entity'), ('count', '1395')]
# [('p', 'http://www.wikidata.org/prop/direct/P101'), ('pname', 'field of work'), ('count', '1379')]
# [('p', 'http://www.wikidata.org/prop/direct/P3219'), ('pname', 'Encyclopædia Universalis ID'), ('count', '1370')]
# [('p', 'http://www.wikidata.org/prop/direct/P22'), ('pname', 'father'), ('count', '1347')]
# [('p', 'http://www.wikidata.org/prop/direct/P8750'), ('pname', 'Unione Romana Biblioteche Scientifiche ID'), ('count', '1340')]
# [('p', 'http://www.wikidata.org/prop/direct/P271'), ('pname', 'CiNii author ID (books)'), ('count', '1310')]
# [('p', 'http://www.wikidata.org/prop/direct/P5570'), ('pname', 'NooSFere author ID'), ('count', '1247')]
# [('p', 'http://www.wikidata.org/prop/direct/P5617'), ('pname', 'Evene ID'), ('count', '1217')]
# [('p', 'http://www.wikidata.org/prop/direct/P2732'), ('pname', 'Persée author ID'), ('count', '1201')]
# [('p', 'http://www.wikidata.org/prop/direct/P937'), ('pname', 'work location'), ('count', '1166')]
# [('p', 'http://www.wikidata.org/prop/direct/P140'), ('pname', 'religion'), ('count', '1153')]
# [('p', 'http://www.wikidata.org/prop/direct/P2963'), ('pname', 'Goodreads author ID'), ('count', '1144')]
# [('p', 'http://www.wikidata.org/prop/direct/P8189'), ('pname', 'National Library of Israel J9U ID'), ('count', '1139')]
# [('p', 'http://www.wikidata.org/prop/direct/P8851'), ('pname', 'CONOR.SR ID'), ('count', '1136')]
# [('p', 'http://www.wikidata.org/prop/direct/P2604'), ('pname', 'Kinopoisk person ID'), ('count', '1121')]
# [('p', 'http://www.wikidata.org/prop/direct/P1233'), ('pname', 'Internet Speculative Fiction Database author ID'), ('count', '1107')]
# [('p', 'http://www.wikidata.org/prop/direct/P3365'), ('pname', 'Treccani ID'), ('count', '1075')]
# [('p', 'http://www.wikidata.org/prop/direct/P1417'), ('pname', 'Encyclopædia Britannica Online ID'), ('count', '1051')]
# [('p', 'http://www.wikidata.org/prop/direct/P6844'), ('pname', 'abART person ID'), ('count', '1047')]
# [('p', 'http://www.wikidata.org/prop/direct/P8179'), ('pname', 'Canadiana NCF ID'), ('count', '1041')]
# [('p', 'http://www.wikidata.org/prop/direct/P1296'), ('pname', 'Gran Enciclopèdia Catalana ID'), ('count', '1034')]
# [('p', 'http://www.wikidata.org/prop/direct/P1266'), ('pname', 'AlloCiné person ID'), ('count', '1029')]
# 100

# %% [markdown]
# #### Let's try with "notable work" (wdt:P800)

# %%
queryString= """
SELECT DISTINCT ?work ?workname WHERE { 

{?writer wdt:P27 wd:Q142;
         wdt:P106 wd:Q36180;
         wdt:P800 ?work.
         }
UNION
{?writer wdt:P27 wd:Q38;
         wdt:P106 wd:Q36180;
         wdt:P800 ?work.
         }

# ?work <http://schema.org/name> ?workname.

}
"""

print("Results")
run_query(queryString)

# %% [markdown]
# #### I inspect the properties to find only the books

# %%
queryString = """
SELECT DISTINCT ?p ?pname (COUNT(?obj) AS ?count) WHERE { 

{?writer wdt:P27 wd:Q142;
         wdt:P106 wd:Q36180;
         wdt:P800 ?work.
# ?work ?p ?obj.
         }
UNION
{?writer wdt:P27 wd:Q38;
         wdt:P106 wd:Q36180;
         wdt:P800 ?work.
# ?work ?p ?obj.
         }

# ?p <http://schema.org/name> ?pname .

}GROUP BY ?p ?pname
ORDER BY DESC (?count)
LIMIT 100
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pname', 'instance of'), ('count', '2290')]
# [('p', 'http://www.wikidata.org/prop/direct/P136'), ('pname', 'genre'), ('count', '1780')]
# [('p', 'http://www.wikidata.org/prop/direct/P50'), ('pname', 'author'), ('count', '1712')]
# [('p', 'http://www.wikidata.org/prop/direct/P577'), ('pname', 'publication date'), ('count', '1679')]
# [('p', 'http://www.wikidata.org/prop/direct/P161'), ('pname', 'cast member'), ('count', '1581')]
# [('p', 'http://www.wikidata.org/prop/direct/P407'), ('pname', 'language of work or name'), ('count', '1428')]
# [('p', 'http://www.wikidata.org/prop/direct/P495'), ('pname', 'country of origin'), ('count', '1280')]
# [('p', 'http://www.wikidata.org/prop/direct/P2671'), ('pname', 'Google Knowledge Graph ID'), ('count', '857')]
# [('p', 'http://www.wikidata.org/prop/direct/P646'), ('pname', 'Freebase ID'), ('count', '734')]
# [('p', 'http://www.wikidata.org/prop/direct/P123'), ('pname', 'publisher'), ('count', '657')]
# [('p', 'http://www.wikidata.org/prop/direct/P747'), ('pname', 'has edition or translation'), ('count', '588')]
# [('p', 'http://www.wikidata.org/prop/direct/P674'), ('pname', 'characters'), ('count', '526')]
# [('p', 'http://www.wikidata.org/prop/direct/P18'), ('pname', 'image'), ('count', '519')]
# [('p', 'http://www.wikidata.org/prop/direct/P268'), ('pname', 'Bibliothèque nationale de France ID'), ('count', '471')]
# [('p', 'http://www.wikidata.org/prop/direct/P4969'), ('pname', 'derivative work'), ('count', '462')]
# [('p', 'http://www.wikidata.org/prop/direct/P921'), ('pname', 'main subject'), ('count', '448')]
# [('p', 'http://www.wikidata.org/prop/direct/P6216'), ('pname', 'copyright status'), ('count', '437')]
# [('p', 'http://www.wikidata.org/prop/direct/P166'), ('pname', 'award received'), ('count', '406')]
# [('p', 'http://www.wikidata.org/prop/direct/P840'), ('pname', 'narrative location'), ('count', '389')]
# [('p', 'http://www.wikidata.org/prop/direct/P212'), ('pname', 'ISBN-13'), ('count', '330')]
# [('p', 'http://www.wikidata.org/prop/direct/P571'), ('pname', 'inception'), ('count', '281')]
# [('p', 'http://www.wikidata.org/prop/direct/P8383'), ('pname', 'Goodreads work ID'), ('count', '279')]
# [('p', 'http://www.wikidata.org/prop/direct/P214'), ('pname', 'VIAF ID'), ('count', '275')]
# [('p', 'http://www.wikidata.org/prop/direct/P243'), ('pname', 'OCLC control number'), ('count', '272')]
# [('p', 'http://www.wikidata.org/prop/direct/P1417'), ('pname', 'Encyclopædia Britannica Online ID'), ('count', '254')]
# [('p', 'http://www.wikidata.org/prop/direct/P5331'), ('pname', 'OCLC work ID'), ('count', '252')]
# [('p', 'http://www.wikidata.org/prop/direct/P180'), ('pname', 'depicts'), ('count', '250')]
# [('p', 'http://www.wikidata.org/prop/direct/P373'), ('pname', 'Commons category'), ('count', '247')]
# [('p', 'http://www.wikidata.org/prop/direct/P2969'), ('pname', 'Goodreads version/edition ID'), ('count', '246')]
# [('p', 'http://www.wikidata.org/prop/direct/P648'), ('pname', 'Open Library ID'), ('count', '244')]
# [('p', 'http://www.wikidata.org/prop/direct/P957'), ('pname', 'ISBN-10'), ('count', '243')]
# [('p', 'http://www.wikidata.org/prop/direct/P58'), ('pname', 'screenwriter'), ('count', '231')]
# [('p', 'http://www.wikidata.org/prop/direct/P227'), ('pname', 'GND ID'), ('count', '202')]
# [('p', 'http://www.wikidata.org/prop/direct/P57'), ('pname', 'director'), ('count', '160')]
# [('p', 'http://www.wikidata.org/prop/direct/P186'), ('pname', 'made from material'), ('count', '158')]
# [('p', 'http://www.wikidata.org/prop/direct/P3959'), ('pname', 'NNL item ID'), ('count', '152')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pname', 'has part'), ('count', '151')]
# [('p', 'http://www.wikidata.org/prop/direct/P170'), ('pname', 'creator'), ('count', '148')]
# [('p', 'http://www.wikidata.org/prop/direct/P86'), ('pname', 'composer'), ('count', '145')]
# [('p', 'http://www.wikidata.org/prop/direct/P364'), ('pname', 'original language of film or TV show'), ('count', '140')]
# [('p', 'http://www.wikidata.org/prop/direct/P345'), ('pname', 'IMDb ID'), ('count', '137')]
# [('p', 'http://www.wikidata.org/prop/direct/P291'), ('pname', 'place of publication'), ('count', '135')]
# [('p', 'http://www.wikidata.org/prop/direct/P3219'), ('pname', 'Encyclopædia Universalis ID'), ('count', '130')]
# [('p', 'http://www.wikidata.org/prop/direct/P4947'), ('pname', 'TMDb movie ID'), ('count', '120')]
# [('p', 'http://www.wikidata.org/prop/direct/P244'), ('pname', 'Library of Congress authority ID'), ('count', '118')]
# [('p', 'http://www.wikidata.org/prop/direct/P156'), ('pname', 'followed by'), ('count', '117')]
# [('p', 'http://www.wikidata.org/prop/direct/P2603'), ('pname', 'Kinopoisk film ID'), ('count', '117')]
# [('p', 'http://www.wikidata.org/prop/direct/P269'), ('pname', 'IdRef ID'), ('count', '117')]
# [('p', 'http://www.wikidata.org/prop/direct/P1889'), ('pname', 'different from'), ('count', '110')]
# [('p', 'http://www.wikidata.org/prop/direct/P2529'), ('pname', 'ČSFD film ID'), ('count', '110')]
# [('p', 'http://www.wikidata.org/prop/direct/P6127'), ('pname', 'Letterboxd film ID'), ('count', '109')]
# [('p', 'http://www.wikidata.org/prop/direct/P1104'), ('pname', 'number of pages'), ('count', '108')]
# [('p', 'http://www.wikidata.org/prop/direct/P1265'), ('pname', 'AlloCiné film ID'), ('count', '107')]
# [('p', 'http://www.wikidata.org/prop/direct/P480'), ('pname', 'FilmAffinity ID'), ('count', '105')]
# [('p', 'http://www.wikidata.org/prop/direct/P17'), ('pname', 'country'), ('count', '104')]
# [('p', 'http://www.wikidata.org/prop/direct/P3143'), ('pname', 'elFilm film ID'), ('count', '104')]
# [('p', 'http://www.wikidata.org/prop/direct/P3138'), ('pname', 'OFDb film ID'), ('count', '104')]
# [('p', 'http://www.wikidata.org/prop/direct/P750'), ('pname', 'distributed by'), ('count', '104')]
# [('p', 'http://www.wikidata.org/prop/direct/P195'), ('pname', 'collection'), ('count', '103')]
# [('p', 'http://www.wikidata.org/prop/direct/P1562'), ('pname', 'AllMovie title ID'), ('count', '102')]
# [('p', 'http://www.wikidata.org/prop/direct/P856'), ('pname', 'official website'), ('count', '101')]
# [('p', 'http://www.wikidata.org/prop/direct/P462'), ('pname', 'color'), ('count', '100')]
# [('p', 'http://www.wikidata.org/prop/direct/P1970'), ('pname', 'MovieMeter film ID'), ('count', '100')]
# [('p', 'http://www.wikidata.org/prop/direct/P2047'), ('pname', 'duration'), ('count', '98')]
# [('p', 'http://www.wikidata.org/prop/direct/P155'), ('pname', 'follows'), ('count', '97')]
# [('p', 'http://www.wikidata.org/prop/direct/P4529'), ('pname', 'Douban film ID'), ('count', '95')]
# [('p', 'http://www.wikidata.org/prop/direct/P276'), ('pname', 'location'), ('count', '94')]
# [('p', 'http://www.wikidata.org/prop/direct/P910'), ('pname', "topic's main category"), ('count', '89')]
# [('p', 'http://www.wikidata.org/prop/direct/P1258'), ('pname', 'Rotten Tomatoes ID'), ('count', '86')]
# [('p', 'http://www.wikidata.org/prop/direct/P973'), ('pname', 'described at URL'), ('count', '86')]
# [('p', 'http://www.wikidata.org/prop/direct/P5032'), ('pname', 'Filmweb.pl film ID'), ('count', '83')]
# [('p', 'http://www.wikidata.org/prop/direct/P162'), ('pname', 'producer'), ('count', '82')]
# [('p', 'http://www.wikidata.org/prop/direct/P217'), ('pname', 'inventory number'), ('count', '82')]
# [('p', 'http://www.wikidata.org/prop/direct/P2704'), ('pname', 'EIDR content ID'), ('count', '82')]
# [('p', 'http://www.wikidata.org/prop/direct/P4276'), ('pname', 'Cinémathèque québécoise work identifier'), ('count', '81')]
# [('p', 'http://www.wikidata.org/prop/direct/P110'), ('pname', 'illustrator'), ('count', '79')]
# [('p', 'http://www.wikidata.org/prop/direct/P2758'), ('pname', 'CNC film rating (France)'), ('count', '78')]
# [('p', 'http://www.wikidata.org/prop/direct/P724'), ('pname', 'Internet Archive ID'), ('count', '78')]
# [('p', 'http://www.wikidata.org/prop/direct/P344'), ('pname', 'director of photography'), ('count', '77')]
# [('p', 'http://www.wikidata.org/prop/direct/P2755'), ('pname', 'exploitation visa number'), ('count', '76')]
# [('p', 'http://www.wikidata.org/prop/direct/P2048'), ('pname', 'height'), ('count', '76')]
# [('p', 'http://www.wikidata.org/prop/direct/P1476'), ('pname', 'title'), ('count', '76')]
# [('p', 'http://www.wikidata.org/prop/direct/P1274'), ('pname', 'ISFDB title ID'), ('count', '74')]
# [('p', 'http://www.wikidata.org/prop/direct/P905'), ('pname', 'PORT film ID'), ('count', '72')]
# [('p', 'http://www.wikidata.org/prop/direct/P135'), ('pname', 'movement'), ('count', '72')]
# [('p', 'http://www.wikidata.org/prop/direct/P2049'), ('pname', 'width'), ('count', '70')]
# [('p', 'http://www.wikidata.org/prop/direct/P5786'), ('pname', 'Moviepilot.de film ID'), ('count', '69')]
# [('p', 'http://www.wikidata.org/prop/direct/P131'), ('pname', 'located in the administrative territorial entity'), ('count', '68')]
# [('p', 'http://www.wikidata.org/prop/direct/P179'), ('pname', 'part of the series'), ('count', '67')]
# [('p', 'http://www.wikidata.org/prop/direct/P3107'), ('pname', 'LdiF ID'), ('count', '66')]
# [('p', 'http://www.wikidata.org/prop/direct/P1085'), ('pname', 'LibraryThing work ID'), ('count', '65')]
# [('p', 'http://www.wikidata.org/prop/direct/P7937'), ('pname', 'form of creative work'), ('count', '65')]
# [('p', 'http://www.wikidata.org/prop/direct/P1040'), ('pname', 'film editor'), ('count', '64')]
# [('p', 'http://www.wikidata.org/prop/direct/P5021'), ('pname', 'assessment'), ('count', '63')]
# [('p', 'http://www.wikidata.org/prop/direct/P5571'), ('pname', 'NooSFere book ID'), ('count', '63')]
# [('p', 'http://www.wikidata.org/prop/direct/P915'), ('pname', 'filming location'), ('count', '61')]
# [('p', 'http://www.wikidata.org/prop/direct/P437'), ('pname', 'distribution format'), ('count', '61')]
# [('p', 'http://www.wikidata.org/prop/direct/P3302'), ('pname', 'Open Media Database film ID'), ('count', '59')]
# [('p', 'http://www.wikidata.org/prop/direct/P1411'), ('pname', 'nominated for'), ('count', '58')]
# [('p', 'http://www.wikidata.org/prop/direct/P3961'), ('pname', 'Unifrance film ID'), ('count', '58')]
# 100

# %% [markdown]
# #### Search in "instance of"

# %%
queryString = """
SELECT DISTINCT ?instance ?instancename (COUNT(?instancename) AS ?count) WHERE { 

{?writer wdt:P27 wd:Q142;
         wdt:P106 wd:Q36180;
         wdt:P800 ?work.
# ?work wdt:P31 ?instance.
         }
UNION
{?writer wdt:P27 wd:Q38;
         wdt:P106 wd:Q36180;
         wdt:P800 ?work.
# ?work wdt:P31 ?instance.
         }

# ?instance <http://schema.org/name> ?instancename.

}
GROUP BY ?instance ?instancename
ORDER BY DESC (?count)
LIMIT 50
"""

print("Results")
run_query(queryString)

# %% [markdown]
# #### I found "written work" (wd:Q47461344), "literary work" (wd:Q7725634), "book" (wd:Q571), "novel" (wd:Q8261)

# %%
queryString = """
SELECT DISTINCT ?work ?workname WHERE { 

{?writer wdt:P27 wd:Q142;
         wdt:P106 wd:Q36180;
         wdt:P800 ?work.
# ?work wdt:P31 ?type.
        }
UNION

{?writer wdt:P27 wd:Q38;
         wdt:P106 wd:Q36180;
         wdt:P800 ?work.
# ?work wdt:P31 ?type.

         }

# ?work <http://schema.org/name> ?workname.

FILTER (?type=wd:Q47461344 || ?type=wd:Q7725634 || ?type=wd:Q571 || ?type=wd:Q8261)
}

"""

print("Results")
run_query(queryString)

# %% [markdown]
# #### I use "publication date"(wdt:P577) found before to select only work published in the last 50 years

# %%
queryString = """
SELECT DISTINCT ?work WHERE { 
{
# ?writer wdt:P27 wd:Q142;
         wdt:P106 wd:Q36180;
         wdt:P800 ?work.
# ?work wdt:P31 ?type;
      wdt:P577 ?date.
}
UNION

{?writer wdt:P27 wd:Q38;
         wdt:P106 wd:Q36180;
         wdt:P800 ?work.
# ?work wdt:P31 ?type;
      wdt:P577 ?date.
         }


FILTER ((?type=wd:Q47461344 || ?type=wd:Q7725634 || ?type=wd:Q571 || ?type=wd:Q8261) && (?date>"1972-01-01T00:00:00Z"^^xsd:dateTime))
}
GROUP BY ?work ?workname
ORDER BY DESC (?authors)

"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('work', 'http://www.wikidata.org/entity/Q3549587')]
# [('work', 'http://www.wikidata.org/entity/Q3226919')]
# [('work', 'http://www.wikidata.org/entity/Q2860454')]
# [('work', 'http://www.wikidata.org/entity/Q16652708')]
# [('work', 'http://www.wikidata.org/entity/Q106368932')]
# [('work', 'http://www.wikidata.org/entity/Q3564414')]
# [('work', 'http://www.wikidata.org/entity/Q18563318')]
# [('work', 'http://www.wikidata.org/entity/Q3365485')]
# [('work', 'http://www.wikidata.org/entity/Q3358641')]
# [('work', 'http://www.wikidata.org/entity/Q18215049')]
# [('work', 'http://www.wikidata.org/entity/Q40014992')]
# [('work', 'http://www.wikidata.org/entity/Q2930400')]
# [('work', 'http://www.wikidata.org/entity/Q2844011')]
# [('work', 'http://www.wikidata.org/entity/Q3234359')]
# [('work', 'http://www.wikidata.org/entity/Q3240199')]
# [('work', 'http://www.wikidata.org/entity/Q668506')]
# [('work', 'http://www.wikidata.org/entity/Q3201748')]
# [('work', 'http://www.wikidata.org/entity/Q3211527')]
# [('work', 'http://www.wikidata.org/entity/Q3222353')]
# [('work', 'http://www.wikidata.org/entity/Q106627054')]
# [('work', 'http://www.wikidata.org/entity/Q67205935')]
# [('work', 'http://www.wikidata.org/entity/Q3221275')]
# [('work', 'http://www.wikidata.org/entity/Q3548905')]
# [('work', 'http://www.wikidata.org/entity/Q44857214')]
# [('work', 'http://www.wikidata.org/entity/Q96676678')]
# [('work', 'http://www.wikidata.org/entity/Q3442632')]
# [('work', 'http://www.wikidata.org/entity/Q3235692')]
# [('work', 'http://www.wikidata.org/entity/Q3201395')]
# [('work', 'http://www.wikidata.org/entity/Q18563346')]
# [('work', 'http://www.wikidata.org/entity/Q7200883')]
# [('work', 'http://www.wikidata.org/entity/Q3235172')]
# [('work', 'http://www.wikidata.org/entity/Q1032190')]
# [('work', 'http://www.wikidata.org/entity/Q3798893')]
# [('work', 'http://www.wikidata.org/entity/Q28668520')]
# [('work', 'http://www.wikidata.org/entity/Q63242763')]
# [('work', 'http://www.wikidata.org/entity/Q17652232')]
# [('work', 'http://www.wikidata.org/entity/Q3793495')]
# [('work', 'http://www.wikidata.org/entity/Q3855482')]
# [('work', 'http://www.wikidata.org/entity/Q2525285')]
# [('work', 'http://www.wikidata.org/entity/Q104119646')]
# [('work', 'http://www.wikidata.org/entity/Q3684178')]
# [('work', 'http://www.wikidata.org/entity/Q22263533')]
# [('work', 'http://www.wikidata.org/entity/Q3040430')]
# [('work', 'http://www.wikidata.org/entity/Q16643170')]
# [('work', 'http://www.wikidata.org/entity/Q20972517')]
# [('work', 'http://www.wikidata.org/entity/Q1425106')]
# [('work', 'http://www.wikidata.org/entity/Q3306777')]
# [('work', 'http://www.wikidata.org/entity/Q3375422')]
# [('work', 'http://www.wikidata.org/entity/Q98442675')]
# [('work', 'http://www.wikidata.org/entity/Q16665207')]
# [('work', 'http://www.wikidata.org/entity/Q82472661')]
# [('work', 'http://www.wikidata.org/entity/Q3232683')]
# [('work', 'http://www.wikidata.org/entity/Q51483246')]
# [('work', 'http://www.wikidata.org/entity/Q99839447')]
# [('work', 'http://www.wikidata.org/entity/Q95741225')]
# [('work', 'http://www.wikidata.org/entity/Q3548650')]
# [('work', 'http://www.wikidata.org/entity/Q3207728')]
# [('work', 'http://www.wikidata.org/entity/Q96606072')]
# [('work', 'http://www.wikidata.org/entity/Q3236533')]
# [('work', 'http://www.wikidata.org/entity/Q21009309')]
# [('work', 'http://www.wikidata.org/entity/Q18563310')]
# [('work', 'http://www.wikidata.org/entity/Q3221961')]
# [('work', 'http://www.wikidata.org/entity/Q96473900')]
# [('work', 'http://www.wikidata.org/entity/Q2379751')]
# [('work', 'http://www.wikidata.org/entity/Q3015359')]
# [('work', 'http://www.wikidata.org/entity/Q3024116')]
# [('work', 'http://www.wikidata.org/entity/Q3553396')]
# [('work', 'http://www.wikidata.org/entity/Q50822036')]
# [('work', 'http://www.wikidata.org/entity/Q24939474')]
# [('work', 'http://www.wikidata.org/entity/Q16657764')]
# [('work', 'http://www.wikidata.org/entity/Q3227183')]
# [('work', 'http://www.wikidata.org/entity/Q3197622')]
# [('work', 'http://www.wikidata.org/entity/Q4305437')]
# [('work', 'http://www.wikidata.org/entity/Q1064945')]
# [('work', 'http://www.wikidata.org/entity/Q7891907')]
# [('work', 'http://www.wikidata.org/entity/Q2868339')]
# [('work', 'http://www.wikidata.org/entity/Q17632469')]
# [('work', 'http://www.wikidata.org/entity/Q24699895')]
# [('work', 'http://www.wikidata.org/entity/Q3207694')]
# [('work', 'http://www.wikidata.org/entity/Q3934011')]
# [('work', 'http://www.wikidata.org/entity/Q64841098')]
# [('work', 'http://www.wikidata.org/entity/Q3995836')]
# [('work', 'http://www.wikidata.org/entity/Q3639402')]
# 512

# %% [markdown]
# #### Now Select only the authors

# %%
queryString = """
SELECT DISTINCT ?writer ?writername WHERE { 
{
# ?writer wdt:P27 wd:Q142;
         wdt:P106 wd:Q36180;
         wdt:P800 ?work.
# ?work wdt:P31 ?type;
      wdt:P577 ?date.
}
UNION

{?writer wdt:P27 wd:Q38;
         wdt:P106 wd:Q36180;
         wdt:P800 ?work.
# ?work wdt:P31 ?type;
      wdt:P577 ?date.
         }

# ?writer <http://schema.org/name> ?writername.

FILTER ((?type=wd:Q47461344 || ?type=wd:Q7725634 || ?type=wd:Q571 || ?type=wd:Q8261) && (?date>"1972-01-01T00:00:00Z"^^xsd:dateTime))
}

"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('writer', 'http://www.wikidata.org/entity/Q435402'), ('writername', 'Sylvie Germain')]
# [('writer', 'http://www.wikidata.org/entity/Q555545'), ('writername', 'Michel del Castillo')]
# [('writer', 'http://www.wikidata.org/entity/Q447507'), ('writername', 'Anne Wiazemsky')]
# [('writer', 'http://www.wikidata.org/entity/Q2296371'), ('writername', 'Soazig Aaron')]
# [('writer', 'http://www.wikidata.org/entity/Q2411481'), ('writername', 'Patrick Deville')]
# [('writer', 'http://www.wikidata.org/entity/Q29766'), ('writername', 'Jean Venturini')]
# [('writer', 'http://www.wikidata.org/entity/Q520892'), ('writername', 'Bernard Clavel')]
# [('writer', 'http://www.wikidata.org/entity/Q380443'), ('writername', 'Alain Finkielkraut')]
# [('writer', 'http://www.wikidata.org/entity/Q3201139'), ('writername', 'Kéthévane Davrichewy')]
# [('writer', 'http://www.wikidata.org/entity/Q92635'), ('writername', 'Jacques Vallée')]
# [('writer', 'http://www.wikidata.org/entity/Q364315'), ('writername', 'Jacques Attali')]
# [('writer', 'http://www.wikidata.org/entity/Q468699'), ('writername', 'Paule Constant')]
# [('writer', 'http://www.wikidata.org/entity/Q295009'), ('writername', "Françoise d'Eaubonne")]
# [('writer', 'http://www.wikidata.org/entity/Q1236969'), ('writername', 'Dominique Noguez')]
# [('writer', 'http://www.wikidata.org/entity/Q2851026'), ('writername', 'Anne Cheynet')]
# [('writer', 'http://www.wikidata.org/entity/Q2853667'), ('writername', 'Antoine Bello')]
# [('writer', 'http://www.wikidata.org/entity/Q2927028'), ('writername', 'Bruno de Cessole')]
# [('writer', 'http://www.wikidata.org/entity/Q2862030'), ('writername', 'Armande Gobry-Valle')]
# [('writer', 'http://www.wikidata.org/entity/Q3160703'), ('writername', 'Jakuta Alikavazovic')]
# [('writer', 'http://www.wikidata.org/entity/Q732644'), ('writername', 'Pierre Michon')]
# [('writer', 'http://www.wikidata.org/entity/Q1163891'), ('writername', 'Frédérick Tristan')]
# [('writer', 'http://www.wikidata.org/entity/Q237684'), ('writername', 'Nancy Huston')]
# [('writer', 'http://www.wikidata.org/entity/Q2941869'), ('writername', 'Catherine Cusset')]
# [('writer', 'http://www.wikidata.org/entity/Q3156009'), ('writername', 'Itxaro Borda')]
# [('writer', 'http://www.wikidata.org/entity/Q3264849'), ('writername', 'Luc Lang')]
# [('writer', 'http://www.wikidata.org/entity/Q151820'), ('writername', 'Louis-Ferdinand Céline')]
# [('writer', 'http://www.wikidata.org/entity/Q1277231'), ('writername', 'Eduardo Manet')]
# [('writer', 'http://www.wikidata.org/entity/Q287828'), ('writername', 'Éric-Emmanuel Schmitt')]
# [('writer', 'http://www.wikidata.org/entity/Q713747'), ('writername', 'Emmanuel Carrère')]
# [('writer', 'http://www.wikidata.org/entity/Q768318'), ('writername', 'Laurent Binet')]
# [('writer', 'http://www.wikidata.org/entity/Q1245984'), ('writername', 'Laurent Gaudé')]
# [('writer', 'http://www.wikidata.org/entity/Q1684760'), ('writername', 'Jean-Claude Izzo')]
# [('writer', 'http://www.wikidata.org/entity/Q287935'), ('writername', 'Patrick Lapeyre')]
# [('writer', 'http://www.wikidata.org/entity/Q153248'), ('writername', 'Marguerite Duras')]
# [('writer', 'http://www.wikidata.org/entity/Q103114'), ('writername', 'Michel Houellebecq')]
# [('writer', 'http://www.wikidata.org/entity/Q3085849'), ('writername', 'François Sonkin')]
# [('writer', 'http://www.wikidata.org/entity/Q3085868'), ('writername', 'François Sureau')]
# [('writer', 'http://www.wikidata.org/entity/Q313852'), ('writername', 'Tzvetan Todorov')]
# [('writer', 'http://www.wikidata.org/entity/Q3490878'), ('writername', 'Sophie Chauveau')]
# [('writer', 'http://www.wikidata.org/entity/Q1153825'), ('writername', 'Annie Ernaux')]
# [('writer', 'http://www.wikidata.org/entity/Q1238567'), ('writername', 'René-Victor Pilhes')]
# [('writer', 'http://www.wikidata.org/entity/Q2941902'), ('writername', 'Catherine Dufour')]
# [('writer', 'http://www.wikidata.org/entity/Q2964194'), ('writername', 'Chloé Delaume')]
# [('writer', 'http://www.wikidata.org/entity/Q3309388'), ('writername', 'Michel Dard')]
# [('writer', 'http://www.wikidata.org/entity/Q3333002'), ('writername', 'Mélusine Vaglio')]
# [('writer', 'http://www.wikidata.org/entity/Q3419549'), ('writername', 'Raphaële Billetdoux')]
# [('writer', 'http://www.wikidata.org/entity/Q3591293'), ('writername', 'Éric Neuhoff')]
# [('writer', 'http://www.wikidata.org/entity/Q469459'), ('writername', 'François Cheng')]
# [('writer', 'http://www.wikidata.org/entity/Q544735'), ('writername', 'Michel Butel')]
# [('writer', 'http://www.wikidata.org/entity/Q3507149'), ('writername', 'Sylvaine Jaoui')]
# [('writer', 'http://www.wikidata.org/entity/Q982361'), ('writername', 'Alexandre Jardin')]
# [('writer', 'http://www.wikidata.org/entity/Q6169743'), ('writername', 'Jean-Paul Alata')]
# [('writer', 'http://www.wikidata.org/entity/Q2068218'), ('writername', 'Raphaël Confiant')]
# [('writer', 'http://www.wikidata.org/entity/Q222944'), ('writername', 'Patrick Modiano')]
# [('writer', 'http://www.wikidata.org/entity/Q736648'), ('writername', 'Jean Dutourd')]
# [('writer', 'http://www.wikidata.org/entity/Q464397'), ('writername', 'Camille Laurens')]
# [('writer', 'http://www.wikidata.org/entity/Q3439561'), ('writername', 'Roger Vrigny')]
# [('writer', 'http://www.wikidata.org/entity/Q470101'), ('writername', 'Hector Bianciotti')]
# [('writer', 'http://www.wikidata.org/entity/Q817411'), ('writername', 'Benjamin Berton')]
# [('writer', 'http://www.wikidata.org/entity/Q1216185'), ('writername', 'Michel Host')]
# [('writer', 'http://www.wikidata.org/entity/Q2829932'), ('writername', 'Alain Jaubert')]
# [('writer', 'http://www.wikidata.org/entity/Q2423280'), ('writername', 'François Aubral')]
# [('writer', 'http://www.wikidata.org/entity/Q18832'), ('writername', 'Sławomir Mrożek')]
# [('writer', 'http://www.wikidata.org/entity/Q3057522'), ('writername', 'Erwan Bergot')]
# [('writer', 'http://www.wikidata.org/entity/Q3571605'), ('writername', 'Yann Apperry')]
# [('writer', 'http://www.wikidata.org/entity/Q1096800'), ('writername', 'Claude Guillon')]
# [('writer', 'http://www.wikidata.org/entity/Q2602209'), ('writername', 'Yves Grevet')]
# [('writer', 'http://www.wikidata.org/entity/Q115243'), ('writername', 'Amin Maalouf')]
# [('writer', 'http://www.wikidata.org/entity/Q1347384'), ('writername', 'Régis Jauffret')]
# [('writer', 'http://www.wikidata.org/entity/Q3121748'), ('writername', 'Guy Dupré')]
# [('writer', 'http://www.wikidata.org/entity/Q448509'), ('writername', 'Vanessa Duriès')]
# [('writer', 'http://www.wikidata.org/entity/Q3110601'), ('writername', 'Gonzague Saint Bris')]
# [('writer', 'http://www.wikidata.org/entity/Q15407411'), ('writername', 'Paul-Gilbert Langevin')]
# [('writer', 'http://www.wikidata.org/entity/Q3475485'), ('writername', 'Scholastique Mukasonga')]
# [('writer', 'http://www.wikidata.org/entity/Q383177'), ('writername', 'Sorj Chalandon')]
# [('writer', 'http://www.wikidata.org/entity/Q15970704'), ('writername', 'Françoise Lefèvre')]
# [('writer', 'http://www.wikidata.org/entity/Q3570582'), ('writername', 'Xavier-Laurent Petit')]
# [('writer', 'http://www.wikidata.org/entity/Q3175156'), ('writername', "Jean d'Aillon")]
# [('writer', 'http://www.wikidata.org/entity/Q60829501'), ('writername', 'Jean-Louis Cheminée')]
# [('writer', 'http://www.wikidata.org/entity/Q93166'), ('writername', 'Milan Kundera')]
# [('writer', 'http://www.wikidata.org/entity/Q380214'), ('writername', 'Andreï Makine')]
# [('writer', 'http://www.wikidata.org/entity/Q62010311'), ('writername', 'Kiyémis')]
# [('writer', 'http://www.wikidata.org/entity/Q459596'), ('writername', 'Danièle Sallenave')]
# [('writer', 'http://www.wikidata.org/entity/Q292463'), ('writername', 'Catherine Millet')]
# [('writer', 'http://www.wikidata.org/entity/Q1079854'), ('writername', 'Christian Giudicelli')]
# [('writer', 'http://www.wikidata.org/entity/Q984448'), ('writername', 'Thomas Piketty')]
# [('writer', 'http://www.wikidata.org/entity/Q63030591'), ('writername', 'Georges Bouvier')]
# [('writer', 'http://www.wikidata.org/entity/Q43389830'), ('writername', 'Jean-René Van der Plaetsen')]
# [('writer', 'http://www.wikidata.org/entity/Q47484'), ('writername', 'André Gide')]
# [('writer', 'http://www.wikidata.org/entity/Q2266390'), ('writername', 'Sylvain Tesson')]
# [('writer', 'http://www.wikidata.org/entity/Q67089108'), ('writername', 'Bérengère Cournut')]
# [('writer', 'http://www.wikidata.org/entity/Q55790020'), ('writername', 'Benjamin Berget')]
# [('writer', 'http://www.wikidata.org/entity/Q2863242'), ('writername', 'Arnaud de La Grange')]
# [('writer', 'http://www.wikidata.org/entity/Q56071962'), ('writername', 'Jacques-Olivier Durand')]
# [('writer', 'http://www.wikidata.org/entity/Q713222'), ('writername', 'Jean-Christophe Rufin')]
# [('writer', 'http://www.wikidata.org/entity/Q671951'), ('writername', 'Gilles Leroy')]
# [('writer', 'http://www.wikidata.org/entity/Q3089661'), ('writername', 'Frédéric Boyer')]
# [('writer', 'http://www.wikidata.org/entity/Q3298851'), ('writername', 'Mathieu Riboulet')]
# [('writer', 'http://www.wikidata.org/entity/Q2850576'), ('writername', 'Anna Moï')]
# [('writer', 'http://www.wikidata.org/entity/Q459641'), ('writername', 'Florence Delay')]
# [('writer', 'http://www.wikidata.org/entity/Q2436895'), ('writername', 'Titaÿna')]
# [('writer', 'http://www.wikidata.org/entity/Q18173445'), ('writername', 'Leïla Slimani')]
# [('writer', 'http://www.wikidata.org/entity/Q79940966'), ('writername', 'Vanessa Springora')]
# [('writer', 'http://www.wikidata.org/entity/Q184226'), ('writername', 'Gilles Deleuze')]
# [('writer', 'http://www.wikidata.org/entity/Q314969'), ('writername', 'Jonathan Littell')]
# [('writer', 'http://www.wikidata.org/entity/Q138166'), ('writername', 'Michel Déon')]
# [('writer', 'http://www.wikidata.org/entity/Q504511'), ('writername', 'Patrick Rambaud')]
# [('writer', 'http://www.wikidata.org/entity/Q81448592'), ('writername', 'Gérard Gertoux')]
# [('writer', 'http://www.wikidata.org/entity/Q3369484'), ('writername', 'Patrick Grainville')]
# [('writer', 'http://www.wikidata.org/entity/Q157313'), ('writername', 'Assia Djebar')]
# [('writer', 'http://www.wikidata.org/entity/Q106277837'), ('writername', 'Inès Bayard')]
# [('writer', 'http://www.wikidata.org/entity/Q220018'), ('writername', 'Anaïs Nin')]
# [('writer', 'http://www.wikidata.org/entity/Q317730'), ('writername', 'Jean-Dominique Bauby')]
# [('writer', 'http://www.wikidata.org/entity/Q17173213'), ('writername', 'Julien Suaudeau')]
# [('writer', 'http://www.wikidata.org/entity/Q21658482'), ('writername', 'Alain Prévost')]
# [('writer', 'http://www.wikidata.org/entity/Q168441'), ('writername', 'Irène Némirovsky')]
# [('writer', 'http://www.wikidata.org/entity/Q43872'), ('writername', 'Jérôme Ferrari')]
# [('writer', 'http://www.wikidata.org/entity/Q1210538'), ('writername', 'Didier Decoin')]
# [('writer', 'http://www.wikidata.org/entity/Q1238611'), ('writername', 'Pierre Combescot')]
# [('writer', 'http://www.wikidata.org/entity/Q740374'), ('writername', 'Joseph Joffo')]
# [('writer', 'http://www.wikidata.org/entity/Q288184'), ('writername', 'Éric Fottorino')]
# [('writer', 'http://www.wikidata.org/entity/Q1235443'), ('writername', 'Pierre Moinot')]
# [('writer', 'http://www.wikidata.org/entity/Q2214373'), ('writername', 'Salim Bachi')]
# [('writer', 'http://www.wikidata.org/entity/Q3084678'), ('writername', 'François Garde')]
# [('writer', 'http://www.wikidata.org/entity/Q2939903'), ('writername', 'Carole Martinez')]
# [('writer', 'http://www.wikidata.org/entity/Q2978027'), ('writername', 'Claude Pujade-Renaud')]
# [('writer', 'http://www.wikidata.org/entity/Q378116'), ('writername', 'Régis Debray')]
# [('writer', 'http://www.wikidata.org/entity/Q3086562'), ('writername', 'Françoise Morvan')]
# [('writer', 'http://www.wikidata.org/entity/Q22750'), ('writername', 'Maurice Genevoix')]
# [('writer', 'http://www.wikidata.org/entity/Q3308896'), ('writername', 'Michel Arrivé')]
# [('writer', 'http://www.wikidata.org/entity/Q157322'), ('writername', 'Romain Gary')]
# [('writer', 'http://www.wikidata.org/entity/Q553135'), ('writername', 'Pierre Péan')]
# [('writer', 'http://www.wikidata.org/entity/Q767547'), ('writername', 'Yann Moix')]
# [('writer', 'http://www.wikidata.org/entity/Q3190911'), ('writername', 'Jérôme Garcin')]
# [('writer', 'http://www.wikidata.org/entity/Q1230705'), ('writername', 'Pascal Lainé')]
# [('writer', 'http://www.wikidata.org/entity/Q3035258'), ('writername', 'Dominique Laporte')]
# [('writer', 'http://www.wikidata.org/entity/Q2959511'), ('writername', 'Charles Juliet')]
# [('writer', 'http://www.wikidata.org/entity/Q3488831'), ('writername', 'Sofia Stril-Rever')]
# [('writer', 'http://www.wikidata.org/entity/Q16540099'), ('writername', 'Claire Delannoy')]
# [('writer', 'http://www.wikidata.org/entity/Q470515'), ('writername', 'Patrick Chamoiseau')]
# [('writer', 'http://www.wikidata.org/entity/Q3154938'), ('writername', 'Isabelle Hausser')]
# [('writer', 'http://www.wikidata.org/entity/Q297794'), ('writername', 'Yasmina Reza')]
# [('writer', 'http://www.wikidata.org/entity/Q3141517'), ('writername', 'Pêr-Jakez Helias')]
# [('writer', 'http://www.wikidata.org/entity/Q348099'), ('writername', 'Kenneth White')]
# [('writer', 'http://www.wikidata.org/entity/Q176246'), ('writername', 'Marc Levy')]
# [('writer', 'http://www.wikidata.org/entity/Q295537'), ('writername', 'Eduard Limonov')]
# [('writer', 'http://www.wikidata.org/entity/Q263201'), ('writername', 'Monique Wittig')]
# [('writer', 'http://www.wikidata.org/entity/Q297510'), ('writername', 'Calixthe Beyala')]
# [('writer', 'http://www.wikidata.org/entity/Q322922'), ('writername', 'Jacques Ellul')]
# [('writer', 'http://www.wikidata.org/entity/Q528173'), ('writername', 'Nine Moati')]
# [('writer', 'http://www.wikidata.org/entity/Q2744164'), ('writername', 'Hélène de Monferrand')]
# [('writer', 'http://www.wikidata.org/entity/Q3165880'), ('writername', 'Jean-François Samlong')]
# [('writer', 'http://www.wikidata.org/entity/Q3345712'), ('writername', 'Christiane Ruiz')]
# [('writer', 'http://www.wikidata.org/entity/Q3193319'), ('writername', 'Karine Tuil')]
# [('writer', 'http://www.wikidata.org/entity/Q23926361'), ('writername', 'Nadia Coste')]
# [('writer', 'http://www.wikidata.org/entity/Q2444124'), ('writername', 'Pierre Bergounioux')]
# [('writer', 'http://www.wikidata.org/entity/Q1375013'), ('writername', 'Sébastien Faure')]
# [('writer', 'http://www.wikidata.org/entity/Q16666494'), ('writername', 'Nicolas Hénin')]
# [('writer', 'http://www.wikidata.org/entity/Q288562'), ('writername', 'Érik Orsenna')]
# [('writer', 'http://www.wikidata.org/entity/Q954370'), ('writername', 'Yann Queffélec')]
# [('writer', 'http://www.wikidata.org/entity/Q722453'), ('writername', 'Didier Van Cauwelaert')]
# [('writer', 'http://www.wikidata.org/entity/Q1227331'), ('writername', 'Frédéric Vitoux')]
# [('writer', 'http://www.wikidata.org/entity/Q1237205'), ('writername', 'Marc Lambron')]
# [('writer', 'http://www.wikidata.org/entity/Q3351202'), ('writername', 'Olivier Mathieu')]
# [('writer', 'http://www.wikidata.org/entity/Q237106'), ('writername', 'Marie NDiaye')]
# [('writer', 'http://www.wikidata.org/entity/Q2896513'), ('writername', 'Benoît Duteurtre')]
# [('writer', 'http://www.wikidata.org/entity/Q773042'), ('writername', 'Jean-Paul Dubois')]
# [('writer', 'http://www.wikidata.org/entity/Q3014616'), ('writername', 'Daniel Rondeau')]
# [('writer', 'http://www.wikidata.org/entity/Q37644555'), ('writername', 'Benjamin Lemaire')]
# [('writer', 'http://www.wikidata.org/entity/Q3086635'), ('writername', 'Françoise Xenakis')]
# [('writer', 'http://www.wikidata.org/entity/Q3074033'), ('writername', 'Florence Seyvos')]
# [('writer', 'http://www.wikidata.org/entity/Q517743'), ('writername', 'André Chamson')]
# [('writer', 'http://www.wikidata.org/entity/Q3310757'), ('writername', 'Michel Rostain')]
# [('writer', 'http://www.wikidata.org/entity/Q3100609'), ('writername', 'Geneviève Brisac')]
# [('writer', 'http://www.wikidata.org/entity/Q1170560'), ('writername', 'Philippe Grimbert')]
# [('writer', 'http://www.wikidata.org/entity/Q273035'), ('writername', 'Benoîte Groult')]
# [('writer', 'http://www.wikidata.org/entity/Q90218733'), ('writername', 'Camille Ammoun')]
# [('writer', 'http://www.wikidata.org/entity/Q274453'), ('writername', 'Anne-Sophie Brasme')]
# [('writer', 'http://www.wikidata.org/entity/Q3369318'), ('writername', 'Claude Klotz')]
# [('writer', 'http://www.wikidata.org/entity/Q3287979'), ('writername', 'Marc Durin-Valois')]
# [('writer', 'http://www.wikidata.org/entity/Q288193'), ('writername', 'Éric Hazan')]
# [('writer', 'http://www.wikidata.org/entity/Q2977820'), ('writername', 'Claude Michelet')]
# [('writer', 'http://www.wikidata.org/entity/Q982029'), ('writername', 'Tony Duvert')]
# [('writer', 'http://www.wikidata.org/entity/Q729151'), ('writername', 'René Belletto')]
# [('writer', 'http://www.wikidata.org/entity/Q101740'), ('writername', 'Benoit Mandelbrot')]
# [('writer', 'http://www.wikidata.org/entity/Q1685081'), ('writername', 'Jean-Michel Guenassia')]
# [('writer', 'http://www.wikidata.org/entity/Q1383662'), ('writername', 'Jean Raspail')]
# [('writer', 'http://www.wikidata.org/entity/Q1237191'), ('writername', 'Bertrand Visage')]
# [('writer', 'http://www.wikidata.org/entity/Q550521'), ('writername', 'Chester Himes')]
# [('writer', 'http://www.wikidata.org/entity/Q3570733'), ('writername', 'Xavier Maniguet')]
# [('writer', 'http://www.wikidata.org/entity/Q17177403'), ('writername', 'Paule du Bouchet')]
# [('writer', 'http://www.wikidata.org/entity/Q1364442'), ('writername', 'Yves Navarre')]
# [('writer', 'http://www.wikidata.org/entity/Q472613'), ('writername', 'Philippe Claudel')]
# [('writer', 'http://www.wikidata.org/entity/Q156268'), ('writername', 'Pierre Bourdieu')]
# [('writer', 'http://www.wikidata.org/entity/Q464150'), ('writername', 'Maylis de Kerangal')]
# [('writer', 'http://www.wikidata.org/entity/Q159876'), ('writername', 'Julia Kristeva')]
# [('writer', 'http://www.wikidata.org/entity/Q464802'), ('writername', 'Shan Sa')]
# [('writer', 'http://www.wikidata.org/entity/Q1345496'), ('writername', 'Jean-Jacques Schuhl')]
# [('writer', 'http://www.wikidata.org/entity/Q622353'), ('writername', 'Alexis Jenni')]
# [('writer', 'http://www.wikidata.org/entity/Q1523224'), ('writername', 'Tobie Nathan')]
# [('writer', 'http://www.wikidata.org/entity/Q982023'), ('writername', 'Jacques Laurent')]
# [('writer', 'http://www.wikidata.org/entity/Q7833'), ('writername', 'Boris Vian')]
# [('writer', 'http://www.wikidata.org/entity/Q17639317'), ('writername', 'Alexandre Grondeau')]
# [('writer', 'http://www.wikidata.org/entity/Q3142466'), ('writername', 'Lucien Bodard')]
# [('writer', 'http://www.wikidata.org/entity/Q217388'), ('writername', 'Anna Gavalda')]
# [('writer', 'http://www.wikidata.org/entity/Q717736'), ('writername', 'Jacques-Pierre Amette')]
# [('writer', 'http://www.wikidata.org/entity/Q47923911'), ('writername', 'Anne-Marie Revol')]
# [('writer', 'http://www.wikidata.org/entity/Q44259273'), ('writername', 'Matthieu Auzanneau')]
# [('writer', 'http://www.wikidata.org/entity/Q353882'), ('writername', 'Jean Echenoz')]
# [('writer', 'http://www.wikidata.org/entity/Q3086462'), ('writername', 'Françoise Dorner')]
# [('writer', 'http://www.wikidata.org/entity/Q3165167'), ('writername', 'Jean-Claude Pertuzé')]
# [('writer', 'http://www.wikidata.org/entity/Q2977367'), ('writername', 'Claude Faraggi')]
# [('writer', 'http://www.wikidata.org/entity/Q3591401'), ('writername', 'Éric Vuillard')]
# [('writer', 'http://www.wikidata.org/entity/Q77020654'), ('writername', 'Cyril Bordier')]
# [('writer', 'http://www.wikidata.org/entity/Q165110'), ('writername', 'Stéphane Hessel')]
# [('writer', 'http://www.wikidata.org/entity/Q42037'), ('writername', 'Jean-Marie Gustave Le Clézio')]
# [('writer', 'http://www.wikidata.org/entity/Q384630'), ('writername', 'Louis Nucera')]
# [('writer', 'http://www.wikidata.org/entity/Q634950'), ('writername', 'Gwenaëlle Aubry')]
# [('writer', 'http://www.wikidata.org/entity/Q3269234'), ('writername', 'Lydie Salvayre')]
# [('writer', 'http://www.wikidata.org/entity/Q295004'), ('writername', 'Fatou Diome')]
# [('writer', 'http://www.wikidata.org/entity/Q16638763'), ('writername', 'Gaël Faye')]
# [('writer', 'http://www.wikidata.org/entity/Q968716'), ('writername', 'Roparz Hemon')]
# [('writer', 'http://www.wikidata.org/entity/Q2073530'), ('writername', 'Jean-Marie Blas de Roblès')]
# [('writer', 'http://www.wikidata.org/entity/Q1412300'), ('writername', 'Hédi Kaddour')]
# [('writer', 'http://www.wikidata.org/entity/Q3293006'), ('writername', 'Marien Defalvard')]
# [('writer', 'http://www.wikidata.org/entity/Q3090225'), ('writername', 'Pascale Roze')]
# [('writer', 'http://www.wikidata.org/entity/Q1236131'), ('writername', 'Jean-Louis Fournier')]
# [('writer', 'http://www.wikidata.org/entity/Q464371'), ('writername', 'Maryse Condé')]
# [('writer', 'http://www.wikidata.org/entity/Q58329491'), ('writername', 'David Diop')]
# [('writer', 'http://www.wikidata.org/entity/Q779144'), ('writername', 'Franck Thilliez')]
# [('writer', 'http://www.wikidata.org/entity/Q1052275'), ('writername', 'Daniel Picouly')]
# [('writer', 'http://www.wikidata.org/entity/Q31017667'), ('writername', 'Boris Razon')]
# [('writer', 'http://www.wikidata.org/entity/Q3258767'), ('writername', 'Lola Lafon')]
# [('writer', 'http://www.wikidata.org/entity/Q442505'), ('writername', 'Dominique Fernandez')]
# [('writer', 'http://www.wikidata.org/entity/Q453288'), ('writername', 'George Steiner')]
# [('writer', 'http://www.wikidata.org/entity/Q1685048'), ('writername', 'Jean-Marie Laclavetine')]
# [('writer', 'http://www.wikidata.org/entity/Q3479419'), ('writername', 'Serge Livrozet')]
# [('writer', 'http://www.wikidata.org/entity/Q34670'), ('writername', 'Antonio carglass')]
# [('writer', 'http://www.wikidata.org/entity/Q3385917'), ('writername', 'Pierre Lemaitre')]
# [('writer', 'http://www.wikidata.org/entity/Q288477'), ('writername', 'Éric Zemmour')]
# [('writer', 'http://www.wikidata.org/entity/Q442534'), ('writername', 'Valérie Tasso')]
# [('writer', 'http://www.wikidata.org/entity/Q163118'), ('writername', 'Marguerite Yourcenar')]
# [('writer', 'http://www.wikidata.org/entity/Q1238602'), ('writername', 'Olivier Rolin')]
# [('writer', 'http://www.wikidata.org/entity/Q982039'), ('writername', 'Jean Rouaud')]
# [('writer', 'http://www.wikidata.org/entity/Q465373'), ('writername', 'Léonora Miano')]
# [('writer', 'http://www.wikidata.org/entity/Q24412623'), ('writername', 'Joseph Andras')]
# [('writer', 'http://www.wikidata.org/entity/Q16028208'), ('writername', 'Alexandre Postel')]
# [('writer', 'http://www.wikidata.org/entity/Q273277'), ('writername', 'Dominique Manotti')]
# [('writer', 'http://www.wikidata.org/entity/Q2898157'), ('writername', 'Bernard Lamarche-Vadel')]
# [('writer', 'http://www.wikidata.org/entity/Q325133'), ('writername', 'David Foenkinos')]
# [('writer', 'http://www.wikidata.org/entity/Q153178'), ('writername', 'Georges Charpak')]
# [('writer', 'http://www.wikidata.org/entity/Q3089678'), ('writername', 'Frédéric Brun')]
# [('writer', 'http://www.wikidata.org/entity/Q61986923'), ('writername', 'Joseph Ponthus')]
# [('writer', 'http://www.wikidata.org/entity/Q65130452'), ('writername', 'Marc Lassus')]
# [('writer', 'http://www.wikidata.org/entity/Q98437224'), ('writername', 'Aude Yung')]
# [('writer', 'http://www.wikidata.org/entity/Q423298'), ('writername', 'Pascal Quignard')]
# [('writer', 'http://www.wikidata.org/entity/Q2347437'), ('writername', 'Jean-Baptiste Del Amo')]
# [('writer', 'http://www.wikidata.org/entity/Q981997'), ('writername', 'Denis Guedj')]
# [('writer', 'http://www.wikidata.org/entity/Q2471163'), ('writername', 'Chantal Thomas')]
# [('writer', 'http://www.wikidata.org/entity/Q669638'), ('writername', 'Catherine Hermary-Vieille')]
# [('writer', 'http://www.wikidata.org/entity/Q25473817'), ('writername', 'Katixa Dolhare-Zaldunbide')]
# [('writer', 'http://www.wikidata.org/entity/Q2314570'), ('writername', 'Tatiana de Rosnay')]
# [('writer', 'http://www.wikidata.org/entity/Q3156126'), ('writername', 'Ivan Jablonka')]
# [('writer', 'http://www.wikidata.org/entity/Q234964'), ('writername', 'Hélène Cixous')]
# [('writer', 'http://www.wikidata.org/entity/Q33476'), ('writername', 'Maryline Desbiolles')]
# [('writer', 'http://www.wikidata.org/entity/Q3179868'), ('writername', 'Jocelyne François')]
# [('writer', 'http://www.wikidata.org/entity/Q3169577'), ('writername', 'Jean-Pierre Milovanoff')]
# [('writer', 'http://www.wikidata.org/entity/Q102083162'), ('writername', 'Sylvain Sorin')]
# [('writer', 'http://www.wikidata.org/entity/Q23302792'), ('writername', 'John Carreyrou')]
# [('writer', 'http://www.wikidata.org/entity/Q15137604'), ('writername', 'Flore Vasseur')]
# [('writer', 'http://www.wikidata.org/entity/Q99202066'), ('writername', 'Pauline Harmange')]
# [('writer', 'http://www.wikidata.org/entity/Q82304220'), ('writername', 'Antoine Sabbagh')]
# [('writer', 'http://www.wikidata.org/entity/Q1685888'), ('writername', 'Jean Vautrin')]
# [('writer', 'http://www.wikidata.org/entity/Q339677'), ('writername', 'Mathias Énard')]
# [('writer', 'http://www.wikidata.org/entity/Q2836569'), ('writername', 'Alice Ferney')]
# [('writer', 'http://www.wikidata.org/entity/Q960088'), ('writername', 'Anne-Marie Garat')]
# [('writer', 'http://www.wikidata.org/entity/Q520691'), ('writername', 'Pierrette Fleutiaux')]
# [('writer', 'http://www.wikidata.org/entity/Q62023761'), ('writername', 'Mireille Berges')]
# [('writer', 'http://www.wikidata.org/entity/Q18214162'), ('writername', 'François Bœspflug')]
# [('writer', 'http://www.wikidata.org/entity/Q459650'), ('writername', 'Eva Cantarella')]
# [('writer', 'http://www.wikidata.org/entity/Q3827806'), ('writername', 'Laura Mancinelli')]
# [('writer', 'http://www.wikidata.org/entity/Q2639944'), ('writername', 'Vittorio Messori')]
# [('writer', 'http://www.wikidata.org/entity/Q25163'), ('writername', 'Roberto Saviano')]
# [('writer', 'http://www.wikidata.org/entity/Q1130896'), ('writername', 'Valerio Evangelisti')]
# [('writer', 'http://www.wikidata.org/entity/Q161933'), ('writername', 'Alberto Moravia')]
# [('writer', 'http://www.wikidata.org/entity/Q153670'), ('writername', 'Primo Levi')]
# [('writer', 'http://www.wikidata.org/entity/Q295589'), ('writername', 'Alessandro Baricco')]
# [('writer', 'http://www.wikidata.org/entity/Q275979'), ('writername', 'Elsa Morante')]
# [('writer', 'http://www.wikidata.org/entity/Q1394495'), ('writername', 'Gesualdo Bufalino')]
# [('writer', 'http://www.wikidata.org/entity/Q276023'), ('writername', 'Susanna Agnelli')]
# [('writer', 'http://www.wikidata.org/entity/Q1364144'), ('writername', 'Gianni Celati')]
# [('writer', 'http://www.wikidata.org/entity/Q12807'), ('writername', 'Umberto Eco')]
# [('writer', 'http://www.wikidata.org/entity/Q2068682'), ('writername', 'Magdalena Tulli')]
# [('writer', 'http://www.wikidata.org/entity/Q355251'), ('writername', 'Carlo Ginzburg')]
# [('writer', 'http://www.wikidata.org/entity/Q332771'), ('writername', 'Ambrogio Fogar')]
# [('writer', 'http://www.wikidata.org/entity/Q604061'), ('writername', 'Antonio Pennacchi')]
# [('writer', 'http://www.wikidata.org/entity/Q1054153'), ('writername', 'Mario Mieli')]
# [('writer', 'http://www.wikidata.org/entity/Q1042470'), ('writername', 'Carlo Rovelli')]
# [('writer', 'http://www.wikidata.org/entity/Q3893530'), ('writername', 'Paola Barbato')]
# [('writer', 'http://www.wikidata.org/entity/Q1449571'), ('writername', 'Francesco Masala')]
# [('writer', 'http://www.wikidata.org/entity/Q1246500'), ('writername', 'Gianrico Carofiglio')]
# [('writer', 'http://www.wikidata.org/entity/Q2037919'), ('writername', 'Salvatore Satta')]
# [('writer', 'http://www.wikidata.org/entity/Q704294'), ('writername', 'Erri De Luca')]
# [('writer', 'http://www.wikidata.org/entity/Q3856792'), ('writername', 'Michele Saponaro')]
# [('writer', 'http://www.wikidata.org/entity/Q3107905'), ('writername', 'Giuliano Scabia')]
# [('writer', 'http://www.wikidata.org/entity/Q3680870'), ('writername', 'Clizia Gurrado')]
# [('writer', 'http://www.wikidata.org/entity/Q231781'), ('writername', 'Antonio Tabucchi')]
# [('writer', 'http://www.wikidata.org/entity/Q47491738'), ('writername', 'Rosella Postorino')]
# [('writer', 'http://www.wikidata.org/entity/Q3609963'), ('writername', "Alessandro D'Avenia")]
# [('writer', 'http://www.wikidata.org/entity/Q3741521'), ('writername', 'Federica Bosco')]
# [('writer', 'http://www.wikidata.org/entity/Q3619926'), ('writername', 'Antonio Moresco')]
# [('writer', 'http://www.wikidata.org/entity/Q107433773'), ('writername', 'Alec Bogdanovic')]
# [('writer', 'http://www.wikidata.org/entity/Q597248'), ('writername', 'Silvia Federici')]
# [('writer', 'http://www.wikidata.org/entity/Q310341'), ('writername', 'Antonio Negri')]
# [('writer', 'http://www.wikidata.org/entity/Q368127'), ('writername', 'Elena Ferrante')]
# [('writer', 'http://www.wikidata.org/entity/Q354755'), ('writername', 'Giulio Angioni')]
# [('writer', 'http://www.wikidata.org/entity/Q234621'), ('writername', 'Susanna Tamaro')]
# [('writer', 'http://www.wikidata.org/entity/Q4004143'), ('writername', 'Una Chi')]
# [('writer', 'http://www.wikidata.org/entity/Q1246106'), ('writername', 'Sandro Veronesi')]
# [('writer', 'http://www.wikidata.org/entity/Q3645940'), ('writername', 'Bruno Tognolini')]
# [('writer', 'http://www.wikidata.org/entity/Q154756'), ('writername', 'Italo Calvino')]
# [('writer', 'http://www.wikidata.org/entity/Q275985'), ('writername', 'Natalia Ginzburg')]
# [('writer', 'http://www.wikidata.org/entity/Q28648754'), ('writername', 'Mirko Zilahy')]
# [('writer', 'http://www.wikidata.org/entity/Q3749403'), ('writername', 'Francesca Fogar')]
# [('writer', 'http://www.wikidata.org/entity/Q311687'), ('writername', 'Giorgio Agamben')]
# [('writer', 'http://www.wikidata.org/entity/Q193018'), ('writername', 'Gianni Rodari')]
# [('writer', 'http://www.wikidata.org/entity/Q66087737'), ('writername', 'Diego Leoni')]
# [('writer', 'http://www.wikidata.org/entity/Q89121593'), ('writername', 'Lorenzo Patruno')]
# [('writer', 'http://www.wikidata.org/entity/Q3050705'), ('writername', 'Elena Gianini Belotti')]
# 329

# %% [markdown]
# ## Task 2 - Compare the number of books written by Italian and French writers

# %%
queryString="""
SELECT DISTINCT ?Country (COUNT(?work) as ?number) WHERE { 


# ?writer wdt:P27 ?nation;
         wdt:P106 wd:Q36180;
         wdt:P800 ?work.
# ?work wdt:P31 ?type.
      

# ?nation <http://schema.org/name> ?Country.
FILTER ((?nation=wd:Q142 || ?nation=wd:Q38) && (?type=wd:Q47461344 || ?type=wd:Q7725634 || ?type=wd:Q571 || ?type=wd:Q8261))
}
GROUP BY ?Country
"""
print("Results")
run_query(queryString)
# Out:
# Results
# [('Country', 'France'), ('number', '1146')]
# [('Country', 'Italy'), ('number', '175')]
# 2

# %% [markdown]
# ## Task 3 - Count how many books written by Italian authors are now released with a "public domain" copyright form

# %% [markdown]
# #### I found "Copyright Status" (wst:P6216). I query all possible values

# %%
queryString= """
SELECT DISTINCT ?obj ?objname WHERE{

# ?writer wdt:P27 wd:Q38;
         wdt:P106 wd:Q36180;
         wdt:P800 ?work.
# ?work wdt:P31 ?type;
      wdt:P6216 ?obj.
    
# ?obj <http://schema.org/name> ?objname.

FILTER (?type=wd:Q47461344 || ?type=wd:Q7725634 || ?type=wd:Q571 || ?type=wd:Q8261)
}

"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('obj', 'http://www.wikidata.org/entity/Q19652'), ('objname', 'public domain')]
# 1

# %% [markdown]
# #### I count them

# %%
queryString= """
SELECT DISTINCT (COUNT(?work) AS ?number) WHERE{

# ?writer wdt:P27 wd:Q38;
         wdt:P106 wd:Q36180;
         wdt:P800 ?work.
# ?work wdt:P31 ?type;
      wdt:P6216 wd:Q19652.
    
FILTER (?type=wd:Q47461344 || ?type=wd:Q7725634 || ?type=wd:Q571 || ?type=wd:Q8261)
}
"""
print("Results")
run_query(queryString)
# Out:
# Results
# [('number', '5')]
# 1

# %%
queryString= """
SELECT DISTINCT ?workname WHERE{

# ?writer wdt:P27 wd:Q38;
         wdt:P106 wd:Q36180;
         wdt:P800 ?work.
# ?work wdt:P31 ?type;
      wdt:P6216 wd:Q19652.

# ?work <http://schema.org/name> ?workname.
FILTER (?type=wd:Q47461344 || ?type=wd:Q7725634 || ?type=wd:Q571 || ?type=wd:Q8261)
}
"""
print("Results")
run_query(queryString)
# Out:
# Results
# [('workname', 'Lives of the Most Excellent Painters, Sculptors, and Architects')]
# [('workname', 'Nibelungenlied')]
# [('workname', 'Captain Blood')]
# [('workname', 'Scaramouche')]
# 4

# %% [markdown]
# ## Task 4 - How many Literature Nobel awards won authors from Italy and from the Kingdom of Italy?

# %% [markdown]
# #### I search  for the properties of the "Nobel Prize in Literature" (wd:Q37922)

# %%
queryString = """
SELECT DISTINCT ?p ?pname WHERE { 

wd:Q37922 ?p ?obj.
# ?p <http://schema.org/name> ?pname.
 }
"""
print("Results")
run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P1296'), ('pname', 'Gran Enciclopèdia Catalana ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pname', 'winner')]
# [('p', 'http://www.wikidata.org/prop/direct/P138'), ('pname', 'named after')]
# [('p', 'http://www.wikidata.org/prop/direct/P1417'), ('pname', 'Encyclopædia Britannica Online ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P17'), ('pname', 'country')]
# [('p', 'http://www.wikidata.org/prop/direct/P1705'), ('pname', 'native label')]
# [('p', 'http://www.wikidata.org/prop/direct/P18'), ('pname', 'image')]
# [('p', 'http://www.wikidata.org/prop/direct/P227'), ('pname', 'GND ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2354'), ('pname', 'has list')]
# [('p', 'http://www.wikidata.org/prop/direct/P2581'), ('pname', 'BabelNet ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P276'), ('pname', 'location')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pname', 'subclass of')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pname', 'instance of')]
# [('p', 'http://www.wikidata.org/prop/direct/P3417'), ('pname', 'Quora topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3509'), ('pname', 'Dagens Nyheter topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3553'), ('pname', 'Zhihu topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3569'), ('pname', 'Cultureel Woordenboek ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P361'), ('pname', 'part of')]
# [('p', 'http://www.wikidata.org/prop/direct/P373'), ('pname', 'Commons category')]
# [('p', 'http://www.wikidata.org/prop/direct/P4342'), ('pname', 'Store norske leksikon ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P444'), ('pname', 'review score')]
# [('p', 'http://www.wikidata.org/prop/direct/P571'), ('pname', 'inception')]
# [('p', 'http://www.wikidata.org/prop/direct/P6081'), ('pname', 'RIA Novosti reference')]
# [('p', 'http://www.wikidata.org/prop/direct/P646'), ('pname', 'Freebase ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8309'), ('pname', 'Yle topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8408'), ('pname', 'KBpedia ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P856'), ('pname', 'official website')]
# [('p', 'http://www.wikidata.org/prop/direct/P910'), ('pname', "topic's main category")]
# [('p', 'http://www.wikidata.org/prop/direct/P9466'), ('pname', 'Gyldendals Teaterleksikon ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P9545'), ('pname', 'Encyclopedia of China Online Database ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1027'), ('pname', 'conferred by')]
# [('p', 'http://www.wikidata.org/prop/direct/P2425'), ('pname', 'service ribbon image')]
# [('p', 'http://www.wikidata.org/prop/direct/P2517'), ('pname', 'category for recipients of this award')]
# 33

# %% [markdown]
# #### I search for all winners (wdt:P1346)

# %%
queryString = """
SELECT DISTINCT ?winner ?winnername WHERE { 

wd:Q37922 wdt:P1346 ?winner.
# ?winner <http://schema.org/name> ?winnername.
 }
"""
print("Results")
run_query(queryString)
# Out:
# Results
# [('winner', 'http://www.wikidata.org/entity/Q159552'), ('winnername', 'Johannes V. Jensen')]
# [('winner', 'http://www.wikidata.org/entity/Q254032'), ('winnername', 'Olga Tokarczuk')]
# [('winner', 'http://www.wikidata.org/entity/Q7241'), ('winnername', 'Rabindranath Tagore')]
# [('winner', 'http://www.wikidata.org/entity/Q392'), ('winnername', 'Bob Dylan')]
# [('winner', 'http://www.wikidata.org/entity/Q44593'), ('winnername', 'V. S. Naipaul')]
# [('winner', 'http://www.wikidata.org/entity/Q121180'), ('winnername', 'Władysław Reymont')]
# [('winner', 'http://www.wikidata.org/entity/Q47561'), ('winnername', 'Ivo Andrić')]
# [('winner', 'http://www.wikidata.org/entity/Q6538'), ('winnername', 'Günter Grass')]
# [('winner', 'http://www.wikidata.org/entity/Q44107'), ('winnername', 'Peter Handke')]
# [('winner', 'http://www.wikidata.org/entity/Q72334'), ('winnername', 'Toni Morrison')]
# [('winner', 'http://www.wikidata.org/entity/Q225554'), ('winnername', 'Henrik Pontoppidan')]
# [('winner', 'http://www.wikidata.org/entity/Q272855'), ('winnername', 'Kazuo Ishiguro')]
# [('winner', 'http://www.wikidata.org/entity/Q47755'), ('winnername', 'Imre Kertész')]
# [('winner', 'http://www.wikidata.org/entity/Q131487'), ('winnername', 'Karl Adolph Gjellerup')]
# [('winner', 'http://www.wikidata.org/entity/Q18143'), ('winnername', 'Gao Xingjian')]
# 15

# %% [markdown]
# #### Few Data i search the other way around starting from "award received"(wdt:P166)  from authors

# %%
queryString = """
SELECT DISTINCT ?award ?awardname WHERE { 

{?writer wdt:P27 wd:Q142;
         wdt:P106 wd:Q36180;
         wdt:P166 ?award.
         }
UNION
{?writer wdt:P27 wd:Q38;
         wdt:P106 wd:Q36180;
         wdt:P166 ?award.
         }

# ?award <http://schema.org/name> ?awardname .

}
"""

print("Results")
run_query(queryString)

# %% [markdown]
# #### Lot of properties i regex only "Nobel"

# %%
queryString = """
SELECT DISTINCT ?award ?awardname WHERE { 

{?writer wdt:P27 wd:Q142;
         wdt:P106 wd:Q36180;
         wdt:P166 ?award.
         }
UNION
{?writer wdt:P27 wd:Q38;
         wdt:P106 wd:Q36180;
         wdt:P166 ?award.
         }

# ?award <http://schema.org/name> ?awardname .
FILTER CONTAINS(?awardname,"Nobel")
}
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('award', 'http://www.wikidata.org/entity/Q35637'), ('awardname', 'Nobel Peace Prize')]
# [('award', 'http://www.wikidata.org/entity/Q37922'), ('awardname', 'Nobel Prize in Literature')]
# [('award', 'http://www.wikidata.org/entity/Q80061'), ('awardname', 'Nobel Prize in Physiology or Medicine')]
# [('award', 'http://www.wikidata.org/entity/Q38104'), ('awardname', 'Nobel Prize in Physics')]
# 4

# %% [markdown]
# #### Found now i select only Italians authors

# %%
queryString = """
SELECT DISTINCT ?writername WHERE { 

# ?writer wdt:P27 ?country;
        wdt:P106 wd:Q36180;
        wdt:P166 wd:Q37922.

# ?writer <http://schema.org/name> ?writername .
FILTER (?country=wd:Q38 || ?country=wd:Q172579)
}
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('writername', 'Grazia Deledda')]
# [('writername', 'Giosuè Carducci')]
# [('writername', 'Luigi Pirandello')]
# [('writername', 'Dario Fo')]
# [('writername', 'Salvatore Quasimodo')]
# 5

# %% [markdown]
# #### I count them

# %%
queryString = """
SELECT DISTINCT (COUNT (DISTINCT ?writer) AS ?number) WHERE { 

# ?writer wdt:P27 ?country;
        wdt:P166 wd:Q37922.

FILTER (?country=wd:Q38 || ?country=wd:Q172579)
}
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('number', '6')]
# 1

# %% [markdown]
# ## Task 5 - Are there books from Litarature Nobel Award winners which are not present in the Vatican Library? (if so, who is the author with more books not in the Vatical Library)?

# %% [markdown]
# #### I search for a property that connects the books of the Nobel winners and Vatican Library(wd:Q213678)

# %%
queryString = """
SELECT DISTINCT ?p ?pname WHERE { 

# ?writer wdt:P166 wd:Q37922;
        wdt:P800 ?work.
# ?work ?p wd:Q213678.

# ?p <http://schema.org/name> ?pname.

}
"""

print("Results")
run_query(queryString)
# Out:
# Results
# Empty
# 0

# %% [markdown]
# #### Found nothing, let's try to inspect the propeterties

# %%
queryString = """
SELECT DISTINCT ?p ?pname WHERE { 

# ?writer wdt:P166 wd:Q37922;
        wdt:P800 ?work.
# ?work ?p ?obj.

# ?p <http://schema.org/name> ?pname.

FILTER CONTAINS(?pname,"Vatican")
}
"""

print("Results")
run_query(queryString)
# Out:
# Results
# Empty
# 0

# %% [markdown]
# #### Still nothing, i search all incoming properties of the Vatican Library

# %%
queryString = """
SELECT DISTINCT ?p ?pname WHERE { 

# ?work ?p wd:Q213678.

# ?p <http://schema.org/name> ?pname.

}
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P2389'), ('pname', 'organization directed by the office or position')]
# [('p', 'http://www.wikidata.org/prop/direct/P9419'), ('pname', 'personal library at')]
# [('p', 'http://www.wikidata.org/prop/direct/P108'), ('pname', 'employer')]
# [('p', 'http://www.wikidata.org/prop/direct/P127'), ('pname', 'owned by')]
# [('p', 'http://www.wikidata.org/prop/direct/P137'), ('pname', 'operator')]
# [('p', 'http://www.wikidata.org/prop/direct/P1416'), ('pname', 'affiliation')]
# [('p', 'http://www.wikidata.org/prop/direct/P189'), ('pname', 'location of discovery')]
# [('p', 'http://www.wikidata.org/prop/direct/P195'), ('pname', 'collection')]
# [('p', 'http://www.wikidata.org/prop/direct/P276'), ('pname', 'location')]
# [('p', 'http://www.wikidata.org/prop/direct/P301'), ('pname', "category's main topic")]
# [('p', 'http://www.wikidata.org/prop/direct/P361'), ('pname', 'part of')]
# [('p', 'http://www.wikidata.org/prop/direct/P485'), ('pname', 'archives at')]
# [('p', 'http://www.wikidata.org/prop/direct/P5869'), ('pname', 'model item')]
# [('p', 'http://www.wikidata.org/prop/direct/P921'), ('pname', 'main subject')]
# [('p', 'http://www.wikidata.org/prop/direct/P971'), ('pname', 'category combines topics')]
# [('p', 'http://www.wikidata.org/prop/direct/P2378'), ('pname', 'issued by')]
# [('p', 'http://www.wikidata.org/prop/direct/P1629'), ('pname', 'Wikidata item of this property')]
# [('p', 'http://www.wikidata.org/prop/direct/P1855'), ('pname', 'Wikidata property example')]
# 18

# %% [markdown]
# #### Try "archives at"(wd:P485)

# %%
queryString = """
SELECT DISTINCT ?work ?workname WHERE { 

# ?work wdt:P485 wd:Q213678.

# ?work <http://schema.org/name> ?workname.

}
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('work', 'http://www.wikidata.org/entity/Q3057287'), ('workname', 'Ernst Steinmann')]
# 1

# %% [markdown]
# #### No...collection(wdt:195)

# %%
queryString = """
SELECT DISTINCT  ?workname WHERE { 

# ?work wdt:P195 wd:Q213678.

# ?work <http://schema.org/name> ?workname.

}
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('workname', 'Bibbia di Federico da Montefeltro - BAV Urb.Lat.1&2')]
# [('workname', 'Codex Vaticanus')]
# [('workname', 'Lasimos Krater')]
# [('workname', 'Bodmer Papyri')]
# [('workname', 'Codex Vaticanus Graecus 64')]
# [('workname', 'Barberini Gospels')]
# [('workname', 'Divina Commedia de Federigo da Montefeltro - BAVaticana UrbLat365')]
# [('workname', 'Book of Dede Korkut')]
# [('workname', 'Rossiana Library')]
# [('workname', 'Vergilius Vaticanus')]
# [('workname', 'Minuscule 131')]
# [('workname', 'Anjou Legendarium')]
# [('workname', 'Codex Vaticanus 354')]
# [('workname', 'Codex Assemanius')]
# [('workname', 'Codex Ríos')]
# [('workname', 'Joshua Roll')]
# [('workname', 'breviary of  Matthias Corvin')]
# [('workname', 'Andrew, the Apostle')]
# [('workname', 'Apostolic Library Regina 1682')]
# [('workname', 'Apostolic Library Reg. 1323')]
# [('workname', 'Codex vaticanus latinus 3199')]
# [('workname', 'Gregorian Sacramentary')]
# [('workname', 'Codex Parisino-petropolitanus')]
# [('workname', 'Chigi codex')]
# [('workname', 'Codex Vaticanus Latinus 3868')]
# [('workname', 'Liber Censuum')]
# [('workname', 'Codex Vaticanus 2061')]
# [('workname', 'Church Slavonic vita of Saint Wenceslaus')]
# [('workname', 'Codex Petropolitanus Purpureus')]
# [('workname', 'Indiculus superstitionum et paganiarum')]
# [('workname', 'Uncial 054')]
# [('workname', 'Lectionary 36')]
# [('workname', 'Vita Mathildis')]
# [('workname', 'Bible of San Paolo fuori le Mura')]
# [('workname', 'Gelasian Sacramentary')]
# [('workname', 'Prochiron legum')]
# [('workname', 'Codex Aureus of Lorsch')]
# [('workname', 'Menologion of Basil II')]
# [('workname', 'Cod. Palat. lat. 1074')]
# [('workname', 'Codex Urbinas')]
# [('workname', 'Dante Urbinate 365')]
# [('workname', 'De arte venandi cum avibus')]
# [('workname', 'Lorsch Bee Blessing')]
# [('workname', 'Papyrus 72')]
# [('workname', 'Vatican Palimpsest')]
# [('workname', 'Apostolic Library Reg. 258')]
# [('workname', 'The Homilies of James of Kokkinobaphos')]
# [('workname', 'Vergilius Romanus')]
# [('workname', 'Papyrus 75')]
# [('workname', 'Codex Borgianus')]
# [('workname', 'Vergilius Augusteus')]
# [('workname', 'Bust of Urban VIII (Vatican Library version)')]
# [('workname', 'Codex Vaticanus 2066')]
# [('workname', 'Hadith Bayad wa Riyad')]
# [('workname', 'Missale Gallicanum vetus - BAV Pal.lat.493')]
# 55

# %% [markdown]
# #### Count the books for each winner that are not in the Vatican Library

# %%
queryString = """
SELECT DISTINCT ?writername (COUNT(?work) AS ?number) WHERE { 

# ?writer wdt:P166 wd:Q37922;
        wdt:P800 ?work.
# ?work wdt:P31 ?type.


# ?writer <http://schema.org/name> ?writername.

FILTER ((?type=wd:Q47461344 || ?type=wd:Q7725634 || ?type=wd:Q571 || ?type=wd:Q8261) && (NOT EXISTS{?work wdt:P195 wd:Q213678.}))
}
GROUP BY(?writername)
ORDER BY DESC (?number)
LIMIT 1
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('writername', 'Thomas Mann'), ('number', '54')]
# 1

# %% [markdown]
# # General instructions
#
# The goal of the project is to materialize a set of **exploratory workloads** over a real-world, large-scale,  open-domain KG: [WikiData](https://www.wikidata.org/wiki/Wikidata:Main_Page)
#
# An exploratory workload  is composed by a set of queries, where each query is related to the information obtained previously.
#
# An exploratory workload starts with a usually vague, open ended question, and does not assume the person issuing the workload has a clear understanding of the data contained in the target database or its structure.
#
# Remeber that:
#
# 1. All the queries must run in the python notebook
# 2. You can use classes and properties only if you find them via a SPARQL query that must be present in the notebook
# 3. You do not delete useless queries. Keep everything that is synthatically valid
#
# ```
# ?p <http://schema.org/name> ?name .
# ```
#
# is the BGP returning a human-readable name of a property or a class in Wikidata.

# %%
## SETUP used later

from SPARQLWrapper import SPARQLWrapper, JSON


prefixString = """
##-b7cf4711ac-##
PREFIX wd: <http://www.wikidata.org/entity/> 
PREFIX wdt: <http://www.wikidata.org/prop/direct/> 
PREFIX sc: <http://schema.org/>
"""

# select and construct queries
def run_query(queryString):
    to_run = prefixString + "\n" + queryString

    sparql = SPARQLWrapper("http://a256-gc1-02.srv.aau.dk:5820/sparql")
    sparql.setTimeout(300)
    sparql.setReturnFormat(JSON)
    sparql.setQuery(to_run)

    try :
       results = sparql.query()
       json_results = results.convert()
       if len(json_results['results']['bindings'])==0:
          print("Empty")
          return 0
    
       for bindings in json_results['results']['bindings']:
          print( [ (var, value['value'])  for var, value in bindings.items() ] )

       return len(json_results['results']['bindings'])

    except Exception as e :
        print("The operation failed", e)
    
# ASk queries
def run_ask_query(queryString):
    to_run = prefixString + "\n" + queryString

    sparql = SPARQLWrapper("http://a256-gc1-02.srv.aau.dk:5820/sparql")
    sparql.setTimeout(300)
    sparql.setReturnFormat(JSON)
    sparql.setQuery(to_run)

    try :
        return sparql.query().convert()

    except Exception as e :
        print("The operation failed", e)

# %% [markdown]
# # GEO Workflow Series ("Place of Birth, Death, and Burial")
#
# Consider the following exploratory information need:
#
# > You want to visit cities connected to famous writers and poets, and you are deciding wether to visit France or Germany

# %% [markdown]
# ## Useful URIs for the current workflow
#
#
# The following are given:
#
# | IRI           | Description   | Role      |
# | -----------   | -----------   |-----------|
# | `wdt:P1647`   | subproperty   | predicate |
# | `wdt:P31`     | instance of   | predicate |
# | `wdt:P279`    | subclass      | predicate |
# | `wdt:P106`    | occupation    | predicate |
# | `wdt:P27`     | citizenship   | predicate |
# | `wd:Q183`     | Germany       | node |
# | `wd:Q142`     | France        | node |
# | `wd:Q90`      | Paris         | node |
# | `wd:Q49757`   | Poet          | node |
# | `wd:Q36180`   | Writer        | node |
# | `wd:Q501`     | Charles Baudelaire  | node      |
# | `wd:Q272208`  | Montparnasse Cemetery       | node |
#
#
# Also consider
#
# ```
# ?p wdt:P27 wd:Q142  .
# ?p wdt:P106 wd:Q36180  .
# ```
#
# is the BGP to retrieve all **French writers**

# %% [markdown]
# ## Workload Goals
#
# 1. Identify the BGP that connect people to their place of birth or place, death, or burial
#
# 2. Identify the BGP to obtain the country in which a place is located
#
# 3. How many poets and writers  have a place of birth, death, or burial in Germany and France?
#
# 4. Analyze cities across the two countries
#
#    4.1 Is there any poet for which the birth place and the place of burial are located in the same city either in Germany or France?
#
#    4.2 Which cities host the place of birth of the larger number of poets or writers across the two countries?
#
#    4.3 What are the top 3 cities in each country that you could visit? Based on what criteria?

# %%
# start your workflow here

# %%
queryString = """
SELECT COUNT(*)
WHERE { 

# ?p wdt:P27 wd:Q142  . 
# ?p wdt:P106 wd:Q36180  . 
} 
GROUP BY ?cult  ?arch
"""

print("Predicates")
run_query(queryString)
# Out:
# Predicates
# [('callret-0', '14400')]
# 1

# %% [markdown]
# ## Task 1
# 1. Identify the BGP that connect people to their place of birth or place, death, or burial

# %%
#From the given URIs I use the one related to "Charles Baudelaire" (wd:Q501) to see if I can find information about place of birth, death and burial looking at the outgoing properties 
queryString = """
SELECT ?pname ?oname ?p ?obj 
WHERE { 

wd:Q501 ?p ?obj .

# ?p <http://schema.org/name> ?pname .
OPTIONAL {?obj <http://schema.org/name> ?oname }.
} 
"""

print("Predicates")
run_query(queryString)
# Out:
# Predicates
# [('pname', 'on focus list of Wikimedia project'), ('oname', 'WikiProject PCC Wikidata Pilot/Frick Art Reference Library'), ('p', 'http://www.wikidata.org/prop/direct/P5008'), ('obj', 'http://www.wikidata.org/entity/Q104694359')]
# [('pname', 'educated at'), ('oname', 'Lycée Louis-le-Grand'), ('p', 'http://www.wikidata.org/prop/direct/P69'), ('obj', 'http://www.wikidata.org/entity/Q1059546')]
# [('pname', 'occupation'), ('oname', 'essayist'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('obj', 'http://www.wikidata.org/entity/Q11774202')]
# [('pname', 'ethnic group'), ('oname', 'French'), ('p', 'http://www.wikidata.org/prop/direct/P172'), ('obj', 'http://www.wikidata.org/entity/Q121842')]
# [('pname', 'country of citizenship'), ('oname', 'France'), ('p', 'http://www.wikidata.org/prop/direct/P27'), ('obj', 'http://www.wikidata.org/entity/Q142')]
# [('pname', 'native language'), ('oname', 'French'), ('p', 'http://www.wikidata.org/prop/direct/P103'), ('obj', 'http://www.wikidata.org/entity/Q150')]
# [('pname', 'languages spoken, written or signed'), ('oname', 'French'), ('p', 'http://www.wikidata.org/prop/direct/P1412'), ('obj', 'http://www.wikidata.org/entity/Q150')]
# [('pname', 'writing language'), ('oname', 'French'), ('p', 'http://www.wikidata.org/prop/direct/P6886'), ('obj', 'http://www.wikidata.org/entity/Q150')]
# [('pname', 'has written for'), ('oname', 'Revue des Deux Mondes'), ('p', 'http://www.wikidata.org/prop/direct/P6872'), ('obj', 'http://www.wikidata.org/entity/Q1569226')]
# [('pname', 'mother'), ('oname', 'Caroline Archenbaut Defayis'), ('p', 'http://www.wikidata.org/prop/direct/P25'), ('obj', 'http://www.wikidata.org/entity/Q15973389')]
# [('pname', 'family name'), ('oname', 'Baudelaire'), ('p', 'http://www.wikidata.org/prop/direct/P734'), ('obj', 'http://www.wikidata.org/entity/Q16479523')]
# [('pname', 'influenced by'), ('oname', 'Edgar Allan Poe'), ('p', 'http://www.wikidata.org/prop/direct/P737'), ('obj', 'http://www.wikidata.org/entity/Q16867')]
# [('pname', 'has works in the collection'), ('oname', 'Minneapolis Institute of Art'), ('p', 'http://www.wikidata.org/prop/direct/P6379'), ('obj', 'http://www.wikidata.org/entity/Q1700481')]
# [('pname', 'described by source'), ('oname', 'Great Soviet Encyclopedia (1969–1978)'), ('p', 'http://www.wikidata.org/prop/direct/P1343'), ('obj', 'http://www.wikidata.org/entity/Q17378135')]
# [('pname', 'genre'), ('oname', 'elegy'), ('p', 'http://www.wikidata.org/prop/direct/P136'), ('obj', 'http://www.wikidata.org/entity/Q174864')]
# [('pname', 'influenced by'), ('oname', 'Théophile Gautier'), ('p', 'http://www.wikidata.org/prop/direct/P737'), ('obj', 'http://www.wikidata.org/entity/Q183713')]
# [('pname', 'religion'), ('oname', 'Catholicism'), ('p', 'http://www.wikidata.org/prop/direct/P140'), ('obj', 'http://www.wikidata.org/entity/Q1841')]
# [('pname', 'influenced by'), ('oname', 'Emmanuel Swedenborg'), ('p', 'http://www.wikidata.org/prop/direct/P737'), ('obj', 'http://www.wikidata.org/entity/Q185832')]
# [('pname', 'described by source'), ('oname', 'Small Brockhaus and Efron Encyclopedic Dictionary'), ('p', 'http://www.wikidata.org/prop/direct/P1343'), ('obj', 'http://www.wikidata.org/entity/Q19180675')]
# [('pname', 'notable work'), ('oname', 'Reflections on Some of My Contemporaries'), ('p', 'http://www.wikidata.org/prop/direct/P800'), ('obj', 'http://www.wikidata.org/entity/Q19227154')]
# [('pname', 'unmarried partner'), ('oname', 'Jeanne Duval'), ('p', 'http://www.wikidata.org/prop/direct/P451'), ('obj', 'http://www.wikidata.org/entity/Q1982279')]
# [('pname', 'given name'), ('oname', 'Pierre'), ('p', 'http://www.wikidata.org/prop/direct/P735'), ('obj', 'http://www.wikidata.org/entity/Q2093070')]
# [('pname', 'notable work'), ('oname', 'Les Fleurs du mal'), ('p', 'http://www.wikidata.org/prop/direct/P800'), ('obj', 'http://www.wikidata.org/entity/Q216578')]
# [('pname', 'notable work'), ('oname', 'Les Paradis artificiels'), ('p', 'http://www.wikidata.org/prop/direct/P800'), ('obj', 'http://www.wikidata.org/entity/Q2249082')]
# [('pname', 'notable work'), ('oname', 'Le Spleen de Paris'), ('p', 'http://www.wikidata.org/prop/direct/P800'), ('obj', 'http://www.wikidata.org/entity/Q2250614')]
# [('pname', 'place of burial'), ('oname', 'Montparnasse Cemetery'), ('p', 'http://www.wikidata.org/prop/direct/P119'), ('obj', 'http://www.wikidata.org/entity/Q272208')]
# [('pname', 'described by source'), ('oname', 'French-language art critics bibliographies'), ('p', 'http://www.wikidata.org/prop/direct/P1343'), ('obj', 'http://www.wikidata.org/entity/Q28923530')]
# [('pname', 'given name'), ('oname', 'Charles'), ('p', 'http://www.wikidata.org/prop/direct/P735'), ('obj', 'http://www.wikidata.org/entity/Q2958359')]
# [('pname', 'influenced by'), ('oname', 'Joseph de Maistre'), ('p', 'http://www.wikidata.org/prop/direct/P737'), ('obj', 'http://www.wikidata.org/entity/Q309854')]
# [('pname', 'influenced by'), ('oname', 'Thomas De Quincey'), ('p', 'http://www.wikidata.org/prop/direct/P737'), ('obj', 'http://www.wikidata.org/entity/Q317160')]
# [('pname', 'described by source'), ('oname', 'The Nuttall Encyclopædia'), ('p', 'http://www.wikidata.org/prop/direct/P1343'), ('obj', 'http://www.wikidata.org/entity/Q3181656')]
# [('pname', 'father'), ('oname', 'Joseph-François Baudelaire'), ('p', 'http://www.wikidata.org/prop/direct/P22'), ('obj', 'http://www.wikidata.org/entity/Q3184256')]
# [('pname', 'notable work'), ('oname', 'Le Peintre de la vie moderne'), ('p', 'http://www.wikidata.org/prop/direct/P800'), ('obj', 'http://www.wikidata.org/entity/Q3225375')]
# [('pname', 'occupation'), ('oname', 'translator'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('obj', 'http://www.wikidata.org/entity/Q333634')]
# [('pname', 'residence'), ('oname', "rue d'Amsterdam"), ('p', 'http://www.wikidata.org/prop/direct/P551'), ('obj', 'http://www.wikidata.org/entity/Q3450470')]
# [('pname', 'occupation'), ('oname', 'writer'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('obj', 'http://www.wikidata.org/entity/Q36180')]
# [('pname', 'manner of death'), ('oname', 'natural causes'), ('p', 'http://www.wikidata.org/prop/direct/P1196'), ('obj', 'http://www.wikidata.org/entity/Q3739104')]
# [('pname', 'cause of death'), ('oname', 'syphilis'), ('p', 'http://www.wikidata.org/prop/direct/P509'), ('obj', 'http://www.wikidata.org/entity/Q41083')]
# [('pname', 'occupation'), ('oname', 'art critic'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('obj', 'http://www.wikidata.org/entity/Q4164507')]
# [('pname', 'occupation'), ('oname', 'literary critic'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('obj', 'http://www.wikidata.org/entity/Q4263842')]
# [('pname', 'influenced by'), ('oname', 'Gustave Flaubert'), ('p', 'http://www.wikidata.org/prop/direct/P737'), ('obj', 'http://www.wikidata.org/entity/Q43444')]
# [('pname', 'field of work'), ('oname', 'poetry'), ('p', 'http://www.wikidata.org/prop/direct/P101'), ('obj', 'http://www.wikidata.org/entity/Q482')]
# [('pname', 'occupation'), ('oname', 'author'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('obj', 'http://www.wikidata.org/entity/Q482980')]
# [('pname', 'occupation'), ('oname', 'poet'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('obj', 'http://www.wikidata.org/entity/Q49757')]
# [('pname', 'instance of'), ('oname', 'human'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('obj', 'http://www.wikidata.org/entity/Q5')]
# [('pname', "topic's main template"), ('oname', 'Template:Charles Baudelaire'), ('p', 'http://www.wikidata.org/prop/direct/P1424'), ('obj', 'http://www.wikidata.org/entity/Q51844662')]
# [('pname', 'described by source'), ('oname', 'BEIC Digital Library'), ('p', 'http://www.wikidata.org/prop/direct/P1343'), ('obj', 'http://www.wikidata.org/entity/Q51955019')]
# [('pname', 'influenced by'), ('oname', 'Victor Hugo'), ('p', 'http://www.wikidata.org/prop/direct/P737'), ('obj', 'http://www.wikidata.org/entity/Q535')]
# [('pname', 'artist files at'), ('oname', 'Frick Art Reference Library'), ('p', 'http://www.wikidata.org/prop/direct/P9493'), ('obj', 'http://www.wikidata.org/entity/Q5503390')]
# [('pname', 'described by source'), ('oname', 'Brockhaus and Efron Encyclopedic Dictionary'), ('p', 'http://www.wikidata.org/prop/direct/P1343'), ('obj', 'http://www.wikidata.org/entity/Q602358')]
# [('pname', 'occupation'), ('oname', 'critic'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('obj', 'http://www.wikidata.org/entity/Q6430706')]
# [('pname', 'notable work'), ('oname', 'La Fanfarlo'), ('p', 'http://www.wikidata.org/prop/direct/P800'), ('obj', 'http://www.wikidata.org/entity/Q6462404')]
# [('pname', 'sex or gender'), ('oname', 'male'), ('p', 'http://www.wikidata.org/prop/direct/P21'), ('obj', 'http://www.wikidata.org/entity/Q6581097')]
# [('pname', 'described by source'), ('oname', 'Obalky knih.cz'), ('p', 'http://www.wikidata.org/prop/direct/P1343'), ('obj', 'http://www.wikidata.org/entity/Q67311526')]
# [('pname', 'described by source'), ('oname', 'Nordisk familjebok'), ('p', 'http://www.wikidata.org/prop/direct/P1343'), ('obj', 'http://www.wikidata.org/entity/Q678259')]
# [('pname', 'influenced by'), ('oname', 'Ovid'), ('p', 'http://www.wikidata.org/prop/direct/P737'), ('obj', 'http://www.wikidata.org/entity/Q7198')]
# [('pname', 'copyright status as a creator'), ('oname', 'works protected by copyrights'), ('p', 'http://www.wikidata.org/prop/direct/P7763'), ('obj', 'http://www.wikidata.org/entity/Q73555012')]
# [('pname', 'patient of'), ('oname', 'Guillaume-Émile Duval'), ('p', 'http://www.wikidata.org/prop/direct/P3205'), ('obj', 'http://www.wikidata.org/entity/Q84794372')]
# [('pname', 'described by source'), ('oname', 'Encyclopædia Britannica 11th edition'), ('p', 'http://www.wikidata.org/prop/direct/P1343'), ('obj', 'http://www.wikidata.org/entity/Q867541')]
# [('pname', 'place of birth'), ('oname', 'Paris'), ('p', 'http://www.wikidata.org/prop/direct/P19'), ('obj', 'http://www.wikidata.org/entity/Q90')]
# [('pname', 'place of death'), ('oname', 'Paris'), ('p', 'http://www.wikidata.org/prop/direct/P20'), ('obj', 'http://www.wikidata.org/entity/Q90')]
# [('pname', 'award received'), ('oname', 'Concours général'), ('p', 'http://www.wikidata.org/prop/direct/P166'), ('obj', 'http://www.wikidata.org/entity/Q908793')]
# [('pname', "topic's main category"), ('oname', 'Category:Charles Baudelaire'), ('p', 'http://www.wikidata.org/prop/direct/P910'), ('obj', 'http://www.wikidata.org/entity/Q9454224')]
# [('pname', 'Portuguese National Library ID'), ('p', 'http://www.wikidata.org/prop/direct/P1005'), ('obj', '14059')]
# [('pname', 'Nationale Thesaurus voor Auteurs ID'), ('p', 'http://www.wikidata.org/prop/direct/P1006'), ('obj', '068364954')]
# [('pname', 'NORAF ID'), ('p', 'http://www.wikidata.org/prop/direct/P1015'), ('obj', '90054929')]
# [('pname', 'Vatican Library ID (former scheme)'), ('p', 'http://www.wikidata.org/prop/direct/P1017'), ('obj', 'ADV10018576')]
# [('pname', 'signature'), ('p', 'http://www.wikidata.org/prop/direct/P109'), ('obj', 'http://commons.wikimedia.org/wiki/Special:FilePath/Baudelaire%20signatur.svg')]
# [('pname', 'Library of Congress Classification'), ('p', 'http://www.wikidata.org/prop/direct/P1149'), ('obj', 'PQ2191')]
# [('pname', 'NUKAT ID'), ('p', 'http://www.wikidata.org/prop/direct/P1207'), ('obj', 'n93080197')]
# [('pname', 'Internet Speculative Fiction Database author ID'), ('p', 'http://www.wikidata.org/prop/direct/P1233'), ('obj', '120635')]
# [('pname', 'NNDB people ID'), ('p', 'http://www.wikidata.org/prop/direct/P1263'), ('obj', '188/000025113')]
# [('pname', 'AlloCiné person ID'), ('p', 'http://www.wikidata.org/prop/direct/P1266'), ('obj', '37038')]
# [('pname', 'CANTIC ID'), ('p', 'http://www.wikidata.org/prop/direct/P1273'), ('obj', 'a10431238')]
# [('pname', 'CONOR.SI ID'), ('p', 'http://www.wikidata.org/prop/direct/P1280'), ('obj', '11594339')]
# [('pname', 'Gran Enciclopèdia Catalana ID'), ('p', 'http://www.wikidata.org/prop/direct/P1296'), ('obj', '0008394')]
# [('pname', 'EGAXA ID'), ('p', 'http://www.wikidata.org/prop/direct/P1309'), ('obj', 'vtls001099115')]
# [('pname', 'NLA Trove ID'), ('p', 'http://www.wikidata.org/prop/direct/P1315'), ('obj', '1214024')]
# [('pname', 'LNB ID'), ('p', 'http://www.wikidata.org/prop/direct/P1368'), ('obj', '000022142')]
# [('pname', 'NSK ID'), ('p', 'http://www.wikidata.org/prop/direct/P1375'), ('obj', '000100605')]
# [('pname', 'Encyclopædia Britannica Online ID'), ('p', 'http://www.wikidata.org/prop/direct/P1417'), ('obj', 'biography/Charles-Baudelaire')]
# [('pname', 'OpenPlaques subject ID'), ('p', 'http://www.wikidata.org/prop/direct/P1430'), ('obj', '7317')]
# [('pname', 'image of grave'), ('p', 'http://www.wikidata.org/prop/direct/P1442'), ('obj', 'http://commons.wikimedia.org/wiki/Special:FilePath/Bodler%20grave.jpg')]
# [('pname', 'Commons Creator page'), ('p', 'http://www.wikidata.org/prop/direct/P1472'), ('obj', 'Charles Baudelaire')]
# [('pname', 'University of Barcelona authority ID'), ('p', 'http://www.wikidata.org/prop/direct/P1580'), ('obj', 'a1244654')]
# [('pname', 'Dialnet author ID'), ('p', 'http://www.wikidata.org/prop/direct/P1607'), ('obj', '784175')]
# [('pname', 'Canadiana Authorities ID (former scheme)'), ('p', 'http://www.wikidata.org/prop/direct/P1670'), ('obj', '0053A1544F')]
# [('pname', 'NLP ID (unique)'), ('p', 'http://www.wikidata.org/prop/direct/P1695'), ('obj', 'A11563722')]
# [('pname', 'British Museum person or institution ID'), ('p', 'http://www.wikidata.org/prop/direct/P1711'), ('obj', '18708')]
# [('pname', 'GTAA ID'), ('p', 'http://www.wikidata.org/prop/direct/P1741'), ('obj', '1670866')]
# [('pname', 'GTAA ID'), ('p', 'http://www.wikidata.org/prop/direct/P1741'), ('obj', '77250')]
# [('pname', 'image'), ('p', 'http://www.wikidata.org/prop/direct/P18'), ('obj', 'http://commons.wikimedia.org/wiki/Special:FilePath/Baudelaire%20crop.jpg')]
# [('pname', 'CERL Thesaurus ID'), ('p', 'http://www.wikidata.org/prop/direct/P1871'), ('obj', 'cnp00543475')]
# [('pname', 'CCAB ID'), ('p', 'http://www.wikidata.org/prop/direct/P1890'), ('obj', '000035729')]
# [('pname', 'LibriVox author ID'), ('p', 'http://www.wikidata.org/prop/direct/P1899'), ('obj', '888')]
# [('pname', 'Project Gutenberg author ID'), ('p', 'http://www.wikidata.org/prop/direct/P1938'), ('obj', '1947')]
# [('pname', 'Discogs artist ID'), ('p', 'http://www.wikidata.org/prop/direct/P1953'), ('obj', '648051')]
# [('pname', 'Les Archives du Spectacle Person ID'), ('p', 'http://www.wikidata.org/prop/direct/P1977'), ('obj', '16188')]
# [('pname', 'Cooper-Hewitt Person ID'), ('p', 'http://www.wikidata.org/prop/direct/P2011'), ('obj', '69120749')]
# [('pname', 'work period (start)'), ('p', 'http://www.wikidata.org/prop/direct/P2031'), ('obj', '1844-01-01T00:00:00Z')]
# [('pname', 'work period (end)'), ('p', 'http://www.wikidata.org/prop/direct/P2032'), ('obj', '1866-01-01T00:00:00Z')]
# [('pname', 'ISNI'), ('p', 'http://www.wikidata.org/prop/direct/P213'), ('obj', '0000 0001 2122 1863')]
# [('pname', 'VIAF ID'), ('p', 'http://www.wikidata.org/prop/direct/P214'), ('obj', '17218730')]
# [('pname', 'FAST ID'), ('p', 'http://www.wikidata.org/prop/direct/P2163'), ('obj', '31368')]
# [('pname', 'BiblioNet author ID'), ('p', 'http://www.wikidata.org/prop/direct/P2188'), ('obj', '428')]
# [('pname', 'Vegetti Catalog of Fantastic Literature NILF ID'), ('p', 'http://www.wikidata.org/prop/direct/P2191'), ('obj', '18330')]
# [('pname', "Musée d'Orsay artist ID"), ('p', 'http://www.wikidata.org/prop/direct/P2268'), ('obj', '2259')]
# [('pname', 'GND ID'), ('p', 'http://www.wikidata.org/prop/direct/P227'), ('obj', '118507184')]
# [('pname', 'AGORHA person/institution ID'), ('p', 'http://www.wikidata.org/prop/direct/P2342'), ('obj', '3493')]
# [('pname', 'Library of Congress authority ID'), ('p', 'http://www.wikidata.org/prop/direct/P244'), ('obj', 'n79018694')]
# [('pname', 'Union List of Artist Names ID'), ('p', 'http://www.wikidata.org/prop/direct/P245'), ('obj', '500046443')]
# [('pname', 'Bibliothèque nationale de France ID'), ('p', 'http://www.wikidata.org/prop/direct/P268'), ('obj', '118905823')]
# [('pname', 'IdRef ID'), ('p', 'http://www.wikidata.org/prop/direct/P269'), ('obj', '026709635')]
# [('pname', 'CiNii author ID (books)'), ('p', 'http://www.wikidata.org/prop/direct/P271'), ('obj', 'DA00522957')]
# [('pname', "Photographers' Identities Catalog ID"), ('p', 'http://www.wikidata.org/prop/direct/P2750'), ('obj', '12878')]
# [('pname', 'BVMC person ID'), ('p', 'http://www.wikidata.org/prop/direct/P2799'), ('obj', '444')]
# [('pname', 'Benezit ID'), ('p', 'http://www.wikidata.org/prop/direct/P2843'), ('obj', 'B00013706')]
# [('pname', 'Great Russian Encyclopedia Online ID'), ('p', 'http://www.wikidata.org/prop/direct/P2924'), ('obj', '1869255')]
# [('pname', 'WikiTree person ID'), ('p', 'http://www.wikidata.org/prop/direct/P2949'), ('obj', 'Baudelaire-1')]
# [('pname', 'Goodreads author ID'), ('p', 'http://www.wikidata.org/prop/direct/P2963'), ('obj', '13847')]
# [('pname', 'National Library of Wales Authority ID'), ('p', 'http://www.wikidata.org/prop/direct/P2966'), ('obj', 'baudelaire-charles-1821-1867')]
# [('pname', 'RERO ID'), ('p', 'http://www.wikidata.org/prop/direct/P3065'), ('obj', '02-A002976871')]
# [('pname', 'Runeberg author ID'), ('p', 'http://www.wikidata.org/prop/direct/P3154'), ('obj', 'baudecha')]
# [('pname', 'Encyclopædia Universalis ID'), ('p', 'http://www.wikidata.org/prop/direct/P3219'), ('obj', 'baudelaire-reperes-chronologiques')]
# [('pname', 'Encyclopædia Universalis ID'), ('p', 'http://www.wikidata.org/prop/direct/P3219'), ('obj', 'charles-baudelaire')]
# [('pname', 'NE.se ID'), ('p', 'http://www.wikidata.org/prop/direct/P3222'), ('obj', 'charles-baudelaire')]
# [('pname', 'BAnQ author ID'), ('p', 'http://www.wikidata.org/prop/direct/P3280'), ('obj', '0000008287')]
# [('pname', 'National Library of Greece ID'), ('p', 'http://www.wikidata.org/prop/direct/P3348'), ('obj', '73055')]
# [('pname', 'Treccani ID'), ('p', 'http://www.wikidata.org/prop/direct/P3365'), ('obj', 'charles-baudelaire')]
# [('pname', 'Quora topic ID'), ('p', 'http://www.wikidata.org/prop/direct/P3417'), ('obj', 'Charles-Baudelaire-author')]
# [('pname', 'SNAC ARK ID'), ('p', 'http://www.wikidata.org/prop/direct/P3430'), ('obj', 'w62z14x7')]
# [('pname', 'IMDb ID'), ('p', 'http://www.wikidata.org/prop/direct/P345'), ('obj', 'nm0061667')]
# [('pname', 'National Diet Library ID'), ('p', 'http://www.wikidata.org/prop/direct/P349'), ('obj', '00432536')]
# [('pname', 'Cultureel Woordenboek ID'), ('p', 'http://www.wikidata.org/prop/direct/P3569'), ('obj', 'literatuur-internationaal/charles-baudelaire')]
# [('pname', 'Minneapolis Institute of Art constituent ID'), ('p', 'http://www.wikidata.org/prop/direct/P3603'), ('obj', '3271')]
# [('pname', 'Babelio author ID'), ('p', 'http://www.wikidata.org/prop/direct/P3630'), ('obj', '2184')]
# [('pname', 'Commons category'), ('p', 'http://www.wikidata.org/prop/direct/P373'), ('obj', 'Charles Baudelaire')]
# [('pname', 'openMLOL author ID'), ('p', 'http://www.wikidata.org/prop/direct/P3762'), ('obj', '1644')]
# [('pname', 'Artnet artist ID'), ('p', 'http://www.wikidata.org/prop/direct/P3782'), ('obj', 'charles-baudelaire')]
# [('pname', 'DBC author ID'), ('p', 'http://www.wikidata.org/prop/direct/P3846'), ('obj', '87097968102731')]
# [('pname', 'Open Library subject ID'), ('p', 'http://www.wikidata.org/prop/direct/P3847'), ('obj', 'baudelaire_charles_1821-1867')]
# [('pname', 'Open Library subject ID'), ('p', 'http://www.wikidata.org/prop/direct/P3847'), ('obj', 'person:charles_baudelaire_(1821-1867)')]
# [('pname', 'SBN author ID'), ('p', 'http://www.wikidata.org/prop/direct/P396'), ('obj', 'IT\\ICCU\\CFIV\\000538')]
# [('pname', 'Bridgeman artist ID'), ('p', 'http://www.wikidata.org/prop/direct/P3965'), ('obj', '18393')]
# [('pname', 'SHARE Catalogue author ID'), ('p', 'http://www.wikidata.org/prop/direct/P3987'), ('obj', '131270')]
# [('pname', 'Libraries Australia ID'), ('p', 'http://www.wikidata.org/prop/direct/P409'), ('obj', '36111104')]
# [('pname', 'Carnegie Hall agent ID'), ('p', 'http://www.wikidata.org/prop/direct/P4104'), ('obj', '1019693')]
# [('pname', "Christie's creator ID"), ('p', 'http://www.wikidata.org/prop/direct/P4200'), ('obj', '54521')]
# [('pname', "Treccani's Enciclopedia Italiana ID"), ('p', 'http://www.wikidata.org/prop/direct/P4223'), ('obj', 'charles-pierre-baudelaire')]
# [('pname', 'MusicBrainz artist ID'), ('p', 'http://www.wikidata.org/prop/direct/P434'), ('obj', 'a6985818-3431-4e4f-a7e9-0d375fdb40f1')]
# [('pname', 'Store norske leksikon ID'), ('p', 'http://www.wikidata.org/prop/direct/P4342'), ('obj', 'Charles_Baudelaire')]
# [('pname', 'gravsted.dk ID'), ('p', 'http://www.wikidata.org/prop/direct/P4359'), ('obj', 'charlesbaudelaire')]
# [('pname', 'pronunciation audio'), ('p', 'http://www.wikidata.org/prop/direct/P443'), ('obj', 'http://commons.wikimedia.org/wiki/Special:FilePath/Fr-Charles%20Baudelaire.oga')]
# [('pname', 'Google Doodle'), ('p', 'http://www.wikidata.org/prop/direct/P4431'), ('obj', 'charles-baudelaires-192nd-birthday')]
# [('pname', 'AKL Online artist ID'), ('p', 'http://www.wikidata.org/prop/direct/P4432'), ('obj', '10109385')]
# [('pname', 'DAHR artist ID'), ('p', 'http://www.wikidata.org/prop/direct/P4457'), ('obj', '102298')]
# [('pname', 'National Library of Brazil ID'), ('p', 'http://www.wikidata.org/prop/direct/P4619'), ('obj', '000593314')]
# [('pname', 'Online Books Page author ID'), ('p', 'http://www.wikidata.org/prop/direct/P4629'), ('obj', 'Baudelaire, Charles, 1821-1867')]
# [('pname', 'Invaluable.com person ID'), ('p', 'http://www.wikidata.org/prop/direct/P4927'), ('obj', 'i2wtgexakj')]
# [('pname', 'TMDb person ID'), ('p', 'http://www.wikidata.org/prop/direct/P4985'), ('obj', '1598820')]
# [('pname', 'Brockhaus Enzyklopädie online ID'), ('p', 'http://www.wikidata.org/prop/direct/P5019'), ('obj', 'baudelaire-charles')]
# [('pname', 'National Library of Korea ID'), ('p', 'http://www.wikidata.org/prop/direct/P5034'), ('obj', 'KAC199601837')]
# [('pname', 'Interlingual Index ID'), ('p', 'http://www.wikidata.org/prop/direct/P5063'), ('obj', 'i94404')]
# [('pname', 'Flanders Arts Institute person ID'), ('p', 'http://www.wikidata.org/prop/direct/P5068'), ('obj', '1893596')]
# [('pname', 'Swedish Literature Bank Author ID'), ('p', 'http://www.wikidata.org/prop/direct/P5101'), ('obj', 'BaudelaireC')]
# [('pname', 'Poetry Foundation ID'), ('p', 'http://www.wikidata.org/prop/direct/P5341'), ('obj', 'charles-baudelaire')]
# [('pname', 'Poets.org poet ID'), ('p', 'http://www.wikidata.org/prop/direct/P5343'), ('obj', 'charles-baudelaire')]
# [('pname', 'Find A Grave memorial ID'), ('p', 'http://www.wikidata.org/prop/direct/P535'), ('obj', '66')]
# [('pname', 'BIU Santé person ID'), ('p', 'http://www.wikidata.org/prop/direct/P5375'), ('obj', '1226')]
# [('pname', 'Les Voix de la poésie poet ID'), ('p', 'http://www.wikidata.org/prop/direct/P5477'), ('obj', 'charles-baudelaire')]
# [('pname', 'RPO poet ID'), ('p', 'http://www.wikidata.org/prop/direct/P5478'), ('obj', 'baudelaire-charles')]
# [('pname', "BD Gest' author ID"), ('p', 'http://www.wikidata.org/prop/direct/P5491'), ('obj', '6019')]
# [('pname', 'RISM ID'), ('p', 'http://www.wikidata.org/prop/direct/P5504'), ('obj', 'pe12121')]
# [('pname', 'NooSFere author ID'), ('p', 'http://www.wikidata.org/prop/direct/P5570'), ('obj', '970')]
# [('pname', 'Libris-URI'), ('p', 'http://www.wikidata.org/prop/direct/P5587'), ('obj', 'ljx00np44ggmsw9')]
# [('pname', 'Bibliothèque de la Pléiade ID'), ('p', 'http://www.wikidata.org/prop/direct/P5613'), ('obj', 'Charles-Baudelaire')]
# [('pname', 'Evene ID'), ('p', 'http://www.wikidata.org/prop/direct/P5617'), ('obj', 'charles-baudelaire-33')]
# [('pname', 'date of birth'), ('p', 'http://www.wikidata.org/prop/direct/P569'), ('obj', '1821-04-09T00:00:00Z')]
# [('pname', 'date of death'), ('p', 'http://www.wikidata.org/prop/direct/P570'), ('obj', '1867-08-31T00:00:00Z')]
# [('pname', 'Angelicum ID'), ('p', 'http://www.wikidata.org/prop/direct/P5731'), ('obj', '45050')]
# [('pname', 'Pontificia Università della Santa Croce ID'), ('p', 'http://www.wikidata.org/prop/direct/P5739'), ('obj', '6364')]
# [('pname', 'ArhivX LOD'), ('p', 'http://www.wikidata.org/prop/direct/P5821'), ('obj', '3020')]
# [('pname', 'Adelphi author ID'), ('p', 'http://www.wikidata.org/prop/direct/P5859'), ('obj', '98')]
# [('pname', 'Muziekweb performer ID'), ('p', 'http://www.wikidata.org/prop/direct/P5882'), ('obj', 'M00000372690')]
# [('pname', 'Comic Vine ID'), ('p', 'http://www.wikidata.org/prop/direct/P5905'), ('obj', '4040-98275')]
# [('pname', 'Bitraga author ID'), ('p', 'http://www.wikidata.org/prop/direct/P6173'), ('obj', '1006')]
# [('pname', 'ELNET ID'), ('p', 'http://www.wikidata.org/prop/direct/P6394'), ('obj', 'a11125664')]
# [('pname', 'TheatreOnline ID'), ('p', 'http://www.wikidata.org/prop/direct/P6403'), ('obj', '14254')]
# [('pname', 'Gran Enciclopèdia de la Música ID'), ('p', 'http://www.wikidata.org/prop/direct/P6412'), ('obj', '15445')]
# [('pname', 'Freebase ID'), ('p', 'http://www.wikidata.org/prop/direct/P646'), ('obj', '/m/01rgr')]
# [('pname', 'Open Library ID'), ('p', 'http://www.wikidata.org/prop/direct/P648'), ('obj', 'OL117429A')]
# [('pname', 'RKDartists ID'), ('p', 'http://www.wikidata.org/prop/direct/P650'), ('obj', '5068')]
# [('pname', 'BHCL ID (former scheme)'), ('p', 'http://www.wikidata.org/prop/direct/P6656'), ('obj', '148429')]
# [('pname', 'Alexander Turnbull Library ID'), ('p', 'http://www.wikidata.org/prop/direct/P6683'), ('obj', '220660')]
# [('pname', 'Orlando author ID'), ('p', 'http://www.wikidata.org/prop/direct/P6745'), ('obj', 'baudch')]
# [('pname', 'abART person ID'), ('p', 'http://www.wikidata.org/prop/direct/P6844'), ('obj', '12695')]
# [('pname', 'IntraText author ID'), ('p', 'http://www.wikidata.org/prop/direct/P6873'), ('obj', '1359')]
# [('pname', 'NKCR AUT ID'), ('p', 'http://www.wikidata.org/prop/direct/P691'), ('obj', 'jn19990000505')]
# [('pname', 'Lebanese National Library ID'), ('p', 'http://www.wikidata.org/prop/direct/P7026'), ('obj', '47518')]
# [('pname', 'National Library of Russia ID'), ('p', 'http://www.wikidata.org/prop/direct/P7029'), ('obj', '7729716')]
# [('pname', 'National Library of Russia ID'), ('p', 'http://www.wikidata.org/prop/direct/P7029'), ('obj', '7745905')]
# [('pname', 'Liber Liber author ID'), ('p', 'http://www.wikidata.org/prop/direct/P7208'), ('obj', 'b/charles-baudelaire')]
# [('pname', 'LyricsTranslate ID'), ('p', 'http://www.wikidata.org/prop/direct/P7212'), ('obj', 'charles-baudelaire-lyrics.html')]
# [('pname', 'Digitale Bibliotheek voor de Nederlandse Letteren author ID'), ('p', 'http://www.wikidata.org/prop/direct/P723'), ('obj', 'baud026')]
# [('pname', 'PLWABN ID'), ('p', 'http://www.wikidata.org/prop/direct/P7293'), ('obj', '9810624789805606')]
# [('pname', 'Aozora Bunko author ID'), ('p', 'http://www.wikidata.org/prop/direct/P7311'), ('obj', '1732')]
# [('pname', 'National Library of Chile ID'), ('p', 'http://www.wikidata.org/prop/direct/P7369'), ('obj', '000008207')]
# [('pname', 'Rijksmuseum Research Library authority ID'), ('p', 'http://www.wikidata.org/prop/direct/P7444'), ('obj', '6972')]
# [('pname', "Edvard Munch's correspondance person ID"), ('p', 'http://www.wikidata.org/prop/direct/P7466'), ('obj', '1212')]
# [('pname', 'Ben Yehuda author ID'), ('p', 'http://www.wikidata.org/prop/direct/P7507'), ('obj', '218')]
# [('pname', 'Visuotinė lietuvių enciklopedija ID'), ('p', 'http://www.wikidata.org/prop/direct/P7666'), ('obj', 'charles-baudelaire')]
# [('pname', 'National Library of Lithuania ID'), ('p', 'http://www.wikidata.org/prop/direct/P7699'), ('obj', 'LNB:V*31947;=BK')]
# [('pname', 'Slovak National Library ID (VIAF)'), ('p', 'http://www.wikidata.org/prop/direct/P7700'), ('obj', 'vtls005584184')]
# [('pname', 'Europeana entity'), ('p', 'http://www.wikidata.org/prop/direct/P7704'), ('obj', 'agent/base/59902')]
# [('pname', 'Projekt Gutenberg-DE ID'), ('p', 'http://www.wikidata.org/prop/direct/P7753'), ('obj', 'baudelai')]
# [('pname', 'French Vikidia ID'), ('p', 'http://www.wikidata.org/prop/direct/P7818'), ('obj', 'Charles_Baudelaire')]
# [('pname', 'Frick Art Reference Library Photoarchive ID'), ('p', 'http://www.wikidata.org/prop/direct/P7848'), ('obj', 'b248447')]
# [('pname', 'WorldCat Identities ID'), ('p', 'http://www.wikidata.org/prop/direct/P7859'), ('obj', 'lccn-n79018694')]
# [('pname', 'CoBiS author ID'), ('p', 'http://www.wikidata.org/prop/direct/P7865'), ('obj', '95a5yja38danygu695b5yc1g60uk6e0')]
# [('pname', 'Deutsche Biographie (GND) ID'), ('p', 'http://www.wikidata.org/prop/direct/P7902'), ('obj', '118507184')]
# [('pname', 'Médias 19 ID'), ('p', 'http://www.wikidata.org/prop/direct/P7918'), ('obj', '14200')]
# [('pname', 'Roglo person ID'), ('p', 'http://www.wikidata.org/prop/direct/P7929'), ('obj', 'p=charles;n=baudelaire')]
# [('pname', 'Vatican Library VcBA ID'), ('p', 'http://www.wikidata.org/prop/direct/P8034'), ('obj', '495/98891')]
# [('pname', 'GeneaStar person ID'), ('p', 'http://www.wikidata.org/prop/direct/P8094'), ('obj', 'baudelaire')]
# [('pname', 'Canadiana NCF ID'), ('p', 'http://www.wikidata.org/prop/direct/P8179'), ('obj', 'ncf10232268')]
# [('pname', 'National Library of Israel J9U ID'), ('p', 'http://www.wikidata.org/prop/direct/P8189'), ('obj', '987007258344405171')]
# [('pname', 'LiederNet author ID'), ('p', 'http://www.wikidata.org/prop/direct/P8234'), ('obj', '163')]
# [('pname', 'Philadelphia Museum of Art entity ID'), ('p', 'http://www.wikidata.org/prop/direct/P8317'), ('obj', '2871')]
# [('pname', 'Proleksis enciklopedija ID'), ('p', 'http://www.wikidata.org/prop/direct/P8349'), ('obj', '11365')]
# [('pname', 'IDU person ID'), ('p', 'http://www.wikidata.org/prop/direct/P8385'), ('obj', '57348')]
# [('pname', 'IMSLP ID'), ('p', 'http://www.wikidata.org/prop/direct/P839'), ('obj', 'Category:Baudelaire,_Charles')]
# [('pname', 'Grove Art Online ID'), ('p', 'http://www.wikidata.org/prop/direct/P8406'), ('obj', 'T006905')]
# [('pname', 'BHF author ID'), ('p', 'http://www.wikidata.org/prop/direct/P8547'), ('obj', '000000459')]
# [('pname', 'Perlentaucher ID'), ('p', 'http://www.wikidata.org/prop/direct/P866'), ('obj', 'charles-baudelaire')]
# [('pname', 'Unione Romana Biblioteche Scientifiche ID'), ('p', 'http://www.wikidata.org/prop/direct/P8750'), ('obj', '25623')]
# [('pname', 'Unione Romana Biblioteche Scientifiche ID'), ('p', 'http://www.wikidata.org/prop/direct/P8750'), ('obj', '25769')]
# [('pname', 'General Diamond Catalogue ID'), ('p', 'http://www.wikidata.org/prop/direct/P8795'), ('obj', '31723')]
# [('pname', 'LIMIS person ID'), ('p', 'http://www.wikidata.org/prop/direct/P8805'), ('obj', '7020977')]
# [('pname', 'WordNet 3.1 Synset ID'), ('p', 'http://www.wikidata.org/prop/direct/P8814'), ('obj', '10858080-n')]
# [('pname', 'Union Catalog of Armenian Libraries authority ID'), ('p', 'http://www.wikidata.org/prop/direct/P8833'), ('obj', '21546')]
# [('pname', 'CONOR.BG ID'), ('p', 'http://www.wikidata.org/prop/direct/P8849'), ('obj', '6548837')]
# [('pname', 'CONOR.SR ID'), ('p', 'http://www.wikidata.org/prop/direct/P8851'), ('obj', '1322599')]
# [('pname', 'Hyperion Records person ID'), ('p', 'http://www.wikidata.org/prop/direct/P8870'), ('obj', 'C728')]
# [('pname', 'Archives at Yale names ID'), ('p', 'http://www.wikidata.org/prop/direct/P8902'), ('obj', 'people/57490')]
# [('pname', 'IPA transcription'), ('p', 'http://www.wikidata.org/prop/direct/P898'), ('obj', 'ʃaʁl bodlɛʁ')]
# [('pname', 'KANTO ID'), ('p', 'http://www.wikidata.org/prop/direct/P8980'), ('obj', '000189569')]
# [('pname', 'BHCL UUID'), ('p', 'http://www.wikidata.org/prop/direct/P9037'), ('obj', '492b7847-fc86-4d59-bf26-053056a63d9c')]
# [('pname', 'SELIBR ID'), ('p', 'http://www.wikidata.org/prop/direct/P906'), ('obj', '176914')]
# [('pname', 'Portal da Literatura ID'), ('p', 'http://www.wikidata.org/prop/direct/P9141'), ('obj', '3858')]
# [('pname', 'Svenska Institutet i Rom ID'), ('p', 'http://www.wikidata.org/prop/direct/P9164'), ('obj', '39123')]
# [('pname', 'RILM ID'), ('p', 'http://www.wikidata.org/prop/direct/P9171'), ('obj', '9041')]
# [('pname', 'ARAE ID'), ('p', 'http://www.wikidata.org/prop/direct/P9226'), ('obj', 'baudelaire-charles-1821-1867')]
# [('pname', 'Cyprus University of Technology ID'), ('p', 'http://www.wikidata.org/prop/direct/P9251'), ('obj', '21343')]
# [('pname', 'Cyprus University of Technology ID'), ('p', 'http://www.wikidata.org/prop/direct/P9251'), ('obj', '78897')]
# [('pname', "Keratsini-Drapetsona libraries' catalogue authority ID"), ('p', 'http://www.wikidata.org/prop/direct/P9337'), ('obj', '77293')]
# [('pname', 'Commons gallery'), ('p', 'http://www.wikidata.org/prop/direct/P935'), ('obj', 'Charles Baudelaire')]
# [('pname', 'FranceArchives agent ID'), ('p', 'http://www.wikidata.org/prop/direct/P9371'), ('obj', '130924379')]
# [('pname', 'Rekhta author ID'), ('p', 'http://www.wikidata.org/prop/direct/P9459'), ('obj', 'charles-baudelaire')]
# [('pname', 'RSL ID (person)'), ('p', 'http://www.wikidata.org/prop/direct/P947'), ('obj', '000035548')]
# [('pname', 'RSL ID (person)'), ('p', 'http://www.wikidata.org/prop/direct/P947'), ('obj', '000035549')]
# [('pname', 'National Library of Israel ID'), ('p', 'http://www.wikidata.org/prop/direct/P949'), ('obj', '000016389')]
# [('pname', 'Biblioteca Nacional de España ID'), ('p', 'http://www.wikidata.org/prop/direct/P950'), ('obj', 'XX1721422')]
# [('pname', 'EBAF authority ID'), ('p', 'http://www.wikidata.org/prop/direct/P9661'), ('obj', '1392')]
# [('pname', 'Classical Archives composer ID'), ('p', 'http://www.wikidata.org/prop/direct/P9686'), ('obj', '79571')]
# [('pname', 'SNK ID'), ('p', 'http://www.wikidata.org/prop/direct/P9807'), ('obj', '174075')]
# 265

# %% [markdown]
# #### Comment
# Looking at these results he have discovered the URIs:
#
# | IRI           | Description   | Role      |
# | -----------   | -----------   |-----------|
# | `wdt:P19`   | place of birth   | predicate |
# | `wdt:P20`     | place of death   | predicate |
# | `wdt:P119`    | place of burial      | predicate |
# | `wd:Q5`    | human    | node |
# | `wd:Q90`    | Paris    | node |
#
# As an example I show the graph pattern to retrieve place of birth, place of death and place of burial of a person (human) without executing it due to the huge number of nodes

# %%
#EXAMPLE - NOT COMPILE
queryString = """
SELECT ?pname ?oname ?p ?obj 
WHERE { 

# ?person ?p ?obj ;  
        wdt:P31 wd:Q5 .

FILTER(?p = wdt:P19 || ?p = wdt:P20 || ?p = wdt:P119).

# ?p <http://schema.org/name> ?pname .
OPTIONAL {?obj <http://schema.org/name> ?oname }.
} 
"""

print("Results")
run_query(queryString)

# %% [markdown]
# ## Task 2
#
# 2. Identify the BGP to obtain the country in which a place is located

# %% [markdown]
# #### Comment
# The solution of this task is similar to the one for task 1 but in this case I'm going to start from Montparnasse Cemetery node (wd:Q272208)

# %%
#From the given URIs I use the one related to "Montparnasse Cemetery" (wd:Q272208) to see if I can find information about the country in which a place is located 
queryString = """
SELECT ?pname ?oname ?p ?obj 
WHERE { 

wd:Q272208 ?p ?obj .

# ?p <http://schema.org/name> ?pname .
OPTIONAL {?obj <http://schema.org/name> ?oname }.
} 
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('pname', 'category of people buried here'), ('oname', 'Category:Burials at Montparnasse Cemetery'), ('p', 'http://www.wikidata.org/prop/direct/P1791'), ('obj', 'http://www.wikidata.org/entity/Q6444336')]
# [('pname', 'country'), ('oname', 'France'), ('p', 'http://www.wikidata.org/prop/direct/P17'), ('obj', 'http://www.wikidata.org/entity/Q142')]
# [('pname', 'country of origin'), ('oname', 'France'), ('p', 'http://www.wikidata.org/prop/direct/P495'), ('obj', 'http://www.wikidata.org/entity/Q142')]
# [('pname', 'located in the administrative territorial entity'), ('oname', '14th arrondissement of Paris'), ('p', 'http://www.wikidata.org/prop/direct/P131'), ('obj', 'http://www.wikidata.org/entity/Q187153')]
# [('pname', 'adjacent building'), ('oname', 'Montparnasse – Bienvenüe'), ('p', 'http://www.wikidata.org/prop/direct/P3032'), ('obj', 'http://www.wikidata.org/entity/Q764465')]
# [('pname', 'located on street'), ('oname', 'boulevard Edgar-Quinet'), ('p', 'http://www.wikidata.org/prop/direct/P669'), ('obj', 'http://www.wikidata.org/entity/Q2921810')]
# [('pname', 'instance of'), ('oname', 'Parisian cemetery'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('obj', 'http://www.wikidata.org/entity/Q2972684')]
# [('pname', 'has part'), ('oname', 'The Kiss'), ('p', 'http://www.wikidata.org/prop/direct/P527'), ('obj', 'http://www.wikidata.org/entity/Q3220192')]
# [('pname', "topic's main category"), ('oname', 'Category:Cimetière du Montparnasse'), ('p', 'http://www.wikidata.org/prop/direct/P910'), ('obj', 'http://www.wikidata.org/entity/Q9594268')]
# [('pname', 'phone number'), ('p', 'http://www.wikidata.org/prop/direct/P1329'), ('obj', '+33-1-44-10-86-50')]
# [('pname', 'GeoNames ID'), ('p', 'http://www.wikidata.org/prop/direct/P1566'), ('obj', '6452784')]
# [('pname', 'place name sign'), ('p', 'http://www.wikidata.org/prop/direct/P1766'), ('obj', 'http://commons.wikimedia.org/wiki/Special:FilePath/Panneau%20Cimeti%C3%A8re%20Montparnasse%20Rue%20%C3%89mile%20Richard%20-%20Paris%20XIV%20%28FR75%29%20-%202021-07-30%20-%201.jpg')]
# [('pname', 'image'), ('p', 'http://www.wikidata.org/prop/direct/P18'), ('obj', 'http://commons.wikimedia.org/wiki/Special:FilePath/Cimeti%C3%A8re%20du%20Montparnasse%20entr%C3%A9e%20principale.jpg')]
# [('pname', 'Find A Grave cemetery ID'), ('p', 'http://www.wikidata.org/prop/direct/P2025'), ('obj', '639007')]
# [('pname', 'area'), ('p', 'http://www.wikidata.org/prop/direct/P2046'), ('obj', '18.72')]
# [('pname', 'postal code'), ('p', 'http://www.wikidata.org/prop/direct/P281'), ('obj', '75014')]
# [('pname', 'FANTOIR code'), ('p', 'http://www.wikidata.org/prop/direct/P3182'), ('obj', '758114B007S')]
# [('pname', 'Commons category'), ('p', 'http://www.wikidata.org/prop/direct/P373'), ('obj', 'Cimetière du Montparnasse')]
# [('pname', 'inception'), ('p', 'http://www.wikidata.org/prop/direct/P571'), ('obj', '1824-01-01T00:00:00Z')]
# [('pname', 'Freebase ID'), ('p', 'http://www.wikidata.org/prop/direct/P646'), ('obj', '/m/096jgl')]
# [('pname', 'Atlas Obscura identifier'), ('p', 'http://www.wikidata.org/prop/direct/P7772'), ('obj', 'montparnasse-cemetery')]
# [('pname', 'French Vikidia ID'), ('p', 'http://www.wikidata.org/prop/direct/P7818'), ('obj', 'Cimetière_du_Montparnasse')]
# [('pname', 'official website'), ('p', 'http://www.wikidata.org/prop/direct/P856'), ('obj', 'http://www.paris.fr/english/heritage-and-sights/cemeteries/montparnasse-cemetery/rub_8222_stand_34190_port_19019')]
# [('pname', 'Commons gallery'), ('p', 'http://www.wikidata.org/prop/direct/P935'), ('obj', 'Cimetière du Montparnasse')]
# [('pname', 'number of graves'), ('p', 'http://www.wikidata.org/prop/direct/P2351'), ('obj', '35000')]
# [('pname', 'Cemeteries of France ID'), ('p', 'http://www.wikidata.org/prop/direct/P8337'), ('obj', '38474')]
# [('pname', 'Sauvons nos tombes cemetery ID'), ('p', 'http://www.wikidata.org/prop/direct/P9189'), ('obj', '8')]
# 27

# %% [markdown]
# #### Comment
# We can see the country of a place but not the city in which a place is located se let's find how to extract this information

# %%
# Properties for Paris
queryString = """
SELECT ?pname ?oname ?p ?obj 
WHERE { 

wd:Q90 ?p ?obj .

# ?p <http://schema.org/name> ?pname .
OPTIONAL {?obj <http://schema.org/name> ?oname }.
} 
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('pname', 'located in or next to body of water'), ('oname', 'Canal Saint-Martin'), ('p', 'http://www.wikidata.org/prop/direct/P206'), ('obj', 'http://www.wikidata.org/entity/Q860172')]
# [('pname', 'category of associated people'), ('oname', 'Category:People from Paris'), ('p', 'http://www.wikidata.org/prop/direct/P1792'), ('obj', 'http://www.wikidata.org/entity/Q8964470')]
# [('pname', 'owner of'), ('oname', 'hôtel Dodun'), ('p', 'http://www.wikidata.org/prop/direct/P1830'), ('obj', 'http://www.wikidata.org/entity/Q19832938')]
# [('pname', 'shares border with'), ('oname', 'Boulogne-Billancourt'), ('p', 'http://www.wikidata.org/prop/direct/P47'), ('obj', 'http://www.wikidata.org/entity/Q172455')]
# [('pname', 'shares border with'), ('oname', 'Aubervilliers'), ('p', 'http://www.wikidata.org/prop/direct/P47'), ('obj', 'http://www.wikidata.org/entity/Q205632')]
# [('pname', 'shares border with'), ('oname', 'Saint-Ouen-sur-Seine'), ('p', 'http://www.wikidata.org/prop/direct/P47'), ('obj', 'http://www.wikidata.org/entity/Q208889')]
# [('pname', 'shares border with'), ('oname', 'Les Lilas'), ('p', 'http://www.wikidata.org/prop/direct/P47'), ('obj', 'http://www.wikidata.org/entity/Q256004')]
# [('pname', 'shares border with'), ('oname', 'Pantin'), ('p', 'http://www.wikidata.org/prop/direct/P47'), ('obj', 'http://www.wikidata.org/entity/Q209086')]
# [('pname', 'shares border with'), ('oname', 'Puteaux'), ('p', 'http://www.wikidata.org/prop/direct/P47'), ('obj', 'http://www.wikidata.org/entity/Q234743')]
# [('pname', 'shares border with'), ('oname', 'Vincennes'), ('p', 'http://www.wikidata.org/prop/direct/P47'), ('obj', 'http://www.wikidata.org/entity/Q193819')]
# [('pname', 'shares border with'), ('oname', 'Saint-Maurice'), ('p', 'http://www.wikidata.org/prop/direct/P47'), ('obj', 'http://www.wikidata.org/entity/Q274327')]
# [('pname', 'owner of'), ('oname', 'Accor Arena'), ('p', 'http://www.wikidata.org/prop/direct/P1830'), ('obj', 'http://www.wikidata.org/entity/Q537720')]
# [('pname', 'replaces'), ('oname', 'Seine'), ('p', 'http://www.wikidata.org/prop/direct/P1365'), ('obj', 'http://www.wikidata.org/entity/Q1142326')]
# [('pname', 'contains administrative territorial entity'), ('oname', '10th arrondissement of Paris'), ('p', 'http://www.wikidata.org/prop/direct/P150'), ('obj', 'http://www.wikidata.org/entity/Q163948')]
# [('pname', 'contains administrative territorial entity'), ('oname', '13th arrondissement of Paris'), ('p', 'http://www.wikidata.org/prop/direct/P150'), ('obj', 'http://www.wikidata.org/entity/Q175129')]
# [('pname', 'shares border with'), ('oname', 'Suresnes'), ('p', 'http://www.wikidata.org/prop/direct/P47'), ('obj', 'http://www.wikidata.org/entity/Q193929')]
# [('pname', 'shares border with'), ('oname', 'Le Pré-Saint-Gervais'), ('p', 'http://www.wikidata.org/prop/direct/P47'), ('obj', 'http://www.wikidata.org/entity/Q175999')]
# [('pname', 'contains administrative territorial entity'), ('oname', '19th arrondissement of Paris'), ('p', 'http://www.wikidata.org/prop/direct/P150'), ('obj', 'http://www.wikidata.org/entity/Q204622')]
# [('pname', 'shares border with'), ('oname', 'Charenton-le-Pont'), ('p', 'http://www.wikidata.org/prop/direct/P47'), ('obj', 'http://www.wikidata.org/entity/Q212793')]
# [('pname', 'shares border with'), ('oname', 'Malakoff'), ('p', 'http://www.wikidata.org/prop/direct/P47'), ('obj', 'http://www.wikidata.org/entity/Q253721')]
# [('pname', 'contains administrative territorial entity'), ('oname', '20th arrondissement of Paris'), ('p', 'http://www.wikidata.org/prop/direct/P150'), ('obj', 'http://www.wikidata.org/entity/Q210720')]
# [('pname', 'replaces'), ('oname', 'Lutetia'), ('p', 'http://www.wikidata.org/prop/direct/P1365'), ('obj', 'http://www.wikidata.org/entity/Q270273')]
# [('pname', 'shares border with'), ('oname', 'Le Kremlin-Bicêtre'), ('p', 'http://www.wikidata.org/prop/direct/P47'), ('obj', 'http://www.wikidata.org/entity/Q135104')]
# [('pname', 'located in the administrative territorial entity'), ('oname', 'Metropolis of Greater Paris'), ('p', 'http://www.wikidata.org/prop/direct/P131'), ('obj', 'http://www.wikidata.org/entity/Q16665915')]
# [('pname', 'capital of'), ('oname', 'Metropolis of Greater Paris'), ('p', 'http://www.wikidata.org/prop/direct/P1376'), ('obj', 'http://www.wikidata.org/entity/Q16665915')]
# [('pname', 'owner of'), ('oname', 'Arc de Triomphe'), ('p', 'http://www.wikidata.org/prop/direct/P1830'), ('obj', 'http://www.wikidata.org/entity/Q64436')]
# [('pname', 'contains administrative territorial entity'), ('oname', 'municipality of Paris'), ('p', 'http://www.wikidata.org/prop/direct/P150'), ('obj', 'http://www.wikidata.org/entity/Q3278478')]
# [('pname', 'award received'), ('oname', 'Knight of the Legion of Honour'), ('p', 'http://www.wikidata.org/prop/direct/P166'), ('obj', 'http://www.wikidata.org/entity/Q10855271')]
# [('pname', 'office held by head of government'), ('oname', 'mayor of Paris'), ('p', 'http://www.wikidata.org/prop/direct/P1313'), ('obj', 'http://www.wikidata.org/entity/Q12371988')]
# [('pname', 'capital of'), ('oname', 'France'), ('p', 'http://www.wikidata.org/prop/direct/P1376'), ('obj', 'http://www.wikidata.org/entity/Q142')]
# [('pname', 'country'), ('oname', 'France'), ('p', 'http://www.wikidata.org/prop/direct/P17'), ('obj', 'http://www.wikidata.org/entity/Q142')]
# [('pname', 'described by source'), ('oname', '1922 Encyclopædia Britannica'), ('p', 'http://www.wikidata.org/prop/direct/P1343'), ('obj', 'http://www.wikidata.org/entity/Q15987490')]
# [('pname', 'shares border with'), ('oname', 'Saint-Denis'), ('p', 'http://www.wikidata.org/prop/direct/P47'), ('obj', 'http://www.wikidata.org/entity/Q160506')]
# [('pname', 'shares border with'), ('oname', 'Saint-Mandé'), ('p', 'http://www.wikidata.org/prop/direct/P47'), ('obj', 'http://www.wikidata.org/entity/Q18102')]
# [('pname', 'contains administrative territorial entity'), ('oname', '14th arrondissement of Paris'), ('p', 'http://www.wikidata.org/prop/direct/P150'), ('obj', 'http://www.wikidata.org/entity/Q187153')]
# [('pname', 'described by source'), ('oname', 'Small Brockhaus and Efron Encyclopedic Dictionary'), ('p', 'http://www.wikidata.org/prop/direct/P1343'), ('obj', 'http://www.wikidata.org/entity/Q19180675')]
# [('pname', 'shares border with'), ('oname', 'Montreuil'), ('p', 'http://www.wikidata.org/prop/direct/P47'), ('obj', 'http://www.wikidata.org/entity/Q193370')]
# [('pname', 'contains administrative territorial entity'), ('oname', '16th arrondissement of Paris'), ('p', 'http://www.wikidata.org/prop/direct/P150'), ('obj', 'http://www.wikidata.org/entity/Q194420')]
# [('pname', 'described by source'), ('oname', 'Ottův slovník naučný'), ('p', 'http://www.wikidata.org/prop/direct/P1343'), ('obj', 'http://www.wikidata.org/entity/Q2041543')]
# [('pname', 'twinned administrative body'), ('oname', 'Rome'), ('p', 'http://www.wikidata.org/prop/direct/P190'), ('obj', 'http://www.wikidata.org/entity/Q220')]
# [('pname', 'contains administrative territorial entity'), ('oname', '5th arrondissement of Paris'), ('p', 'http://www.wikidata.org/prop/direct/P150'), ('obj', 'http://www.wikidata.org/entity/Q238723')]
# [('pname', 'contains administrative territorial entity'), ('oname', '6th arrondissement of Paris'), ('p', 'http://www.wikidata.org/prop/direct/P150'), ('obj', 'http://www.wikidata.org/entity/Q245546')]
# [('pname', 'contains administrative territorial entity'), ('oname', '7th arrondissement of Paris'), ('p', 'http://www.wikidata.org/prop/direct/P150'), ('obj', 'http://www.wikidata.org/entity/Q259463')]
# [('pname', 'contains administrative territorial entity'), ('oname', '8th arrondissement of Paris'), ('p', 'http://www.wikidata.org/prop/direct/P150'), ('obj', 'http://www.wikidata.org/entity/Q270230')]
# [('pname', 'award received'), ('oname', 'Croix de guerre 1914–1918'), ('p', 'http://www.wikidata.org/prop/direct/P166'), ('obj', 'http://www.wikidata.org/entity/Q2727598')]
# [('pname', 'contains administrative territorial entity'), ('oname', '9th arrondissement of Paris'), ('p', 'http://www.wikidata.org/prop/direct/P150'), ('obj', 'http://www.wikidata.org/entity/Q275118')]
# [('pname', 'described by source'), ('oname', 'Catholic Encyclopedia'), ('p', 'http://www.wikidata.org/prop/direct/P1343'), ('obj', 'http://www.wikidata.org/entity/Q302556')]
# [('pname', 'described by source'), ('oname', 'Regesta Imperii'), ('p', 'http://www.wikidata.org/prop/direct/P1343'), ('obj', 'http://www.wikidata.org/entity/Q316838')]
# [('pname', 'described by source'), ('oname', 'The Nuttall Encyclopædia'), ('p', 'http://www.wikidata.org/prop/direct/P1343'), ('obj', 'http://www.wikidata.org/entity/Q3181656')]
# [('pname', 'described by source'), ('oname', 'Sytin Military Encyclopedia'), ('p', 'http://www.wikidata.org/prop/direct/P1343'), ('obj', 'http://www.wikidata.org/entity/Q4114391')]
# [('pname', 'described by source'), ('oname', 'Jewish Encyclopedia of Brockhaus and Efron'), ('p', 'http://www.wikidata.org/prop/direct/P1343'), ('obj', 'http://www.wikidata.org/entity/Q4173137')]
# [('pname', 'continent'), ('oname', 'Europe'), ('p', 'http://www.wikidata.org/prop/direct/P30'), ('obj', 'http://www.wikidata.org/entity/Q46')]
# [('pname', 'present in work'), ('oname', 'Federation – The First 150 Years'), ('p', 'http://www.wikidata.org/prop/direct/P1441'), ('obj', 'http://www.wikidata.org/entity/Q47468233')]
# [('pname', 'shares border with'), ('oname', 'Neuilly-sur-Seine'), ('p', 'http://www.wikidata.org/prop/direct/P47'), ('obj', 'http://www.wikidata.org/entity/Q48958')]
# [('pname', 'instance of'), ('oname', 'capital'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('obj', 'http://www.wikidata.org/entity/Q5119')]
# [('pname', 'on focus list of Wikimedia project'), ('oname', 'Wikipedia:Vital articles'), ('p', 'http://www.wikidata.org/prop/direct/P5008'), ('obj', 'http://www.wikidata.org/entity/Q5460604')]
# [('pname', 'described by source'), ('oname', 'Brockhaus and Efron Encyclopedic Dictionary'), ('p', 'http://www.wikidata.org/prop/direct/P1343'), ('obj', 'http://www.wikidata.org/entity/Q602358')]
# [('pname', 'located in time zone'), ('oname', 'UTC+01:00'), ('p', 'http://www.wikidata.org/prop/direct/P421'), ('obj', 'http://www.wikidata.org/entity/Q6655')]
# [('pname', 'located in time zone'), ('oname', 'UTC+02:00'), ('p', 'http://www.wikidata.org/prop/direct/P421'), ('obj', 'http://www.wikidata.org/entity/Q6723')]
# [('pname', 'described by source'), ('oname', 'Encyclopædia Britannica 11th edition'), ('p', 'http://www.wikidata.org/prop/direct/P1343'), ('obj', 'http://www.wikidata.org/entity/Q867541')]
# [('pname', 'shares border with'), ('oname', 'Hauts-de-Seine'), ('p', 'http://www.wikidata.org/prop/direct/P47'), ('obj', 'http://www.wikidata.org/entity/Q12543')]
# [('pname', 'shares border with'), ('oname', 'Seine-Saint-Denis'), ('p', 'http://www.wikidata.org/prop/direct/P47'), ('obj', 'http://www.wikidata.org/entity/Q12761')]
# [('pname', 'shares border with'), ('oname', 'Val-de-Marne'), ('p', 'http://www.wikidata.org/prop/direct/P47'), ('obj', 'http://www.wikidata.org/entity/Q12788')]
# [('pname', 'shares border with'), ('oname', 'Issy-les-Moulineaux'), ('p', 'http://www.wikidata.org/prop/direct/P47'), ('obj', 'http://www.wikidata.org/entity/Q135265')]
# [('pname', 'part of'), ('oname', 'Île-de-France'), ('p', 'http://www.wikidata.org/prop/direct/P361'), ('obj', 'http://www.wikidata.org/entity/Q13917')]
# [('pname', 'shares border with'), ('oname', 'Levallois-Perret'), ('p', 'http://www.wikidata.org/prop/direct/P47'), ('obj', 'http://www.wikidata.org/entity/Q166640')]
# [('pname', 'contains administrative territorial entity'), ('oname', '17th arrondissement of Paris'), ('p', 'http://www.wikidata.org/prop/direct/P150'), ('obj', 'http://www.wikidata.org/entity/Q197297')]
# [('pname', 'shares border with'), ('oname', 'Clichy'), ('p', 'http://www.wikidata.org/prop/direct/P47'), ('obj', 'http://www.wikidata.org/entity/Q201982')]
# [('pname', 'shares border with'), ('oname', 'Bagnolet'), ('p', 'http://www.wikidata.org/prop/direct/P47'), ('obj', 'http://www.wikidata.org/entity/Q208943')]
# [('pname', 'owner of'), ('oname', 'Eiffel Tower'), ('p', 'http://www.wikidata.org/prop/direct/P1830'), ('obj', 'http://www.wikidata.org/entity/Q243')]
# [('pname', 'present in work'), ('oname', 'Remembrance'), ('p', 'http://www.wikidata.org/prop/direct/P1441'), ('obj', 'http://www.wikidata.org/entity/Q63892451')]
# [('pname', 'significant event'), ('oname', 'Siege of Paris'), ('p', 'http://www.wikidata.org/prop/direct/P793'), ('obj', 'http://www.wikidata.org/entity/Q690489')]
# [('pname', 'patron saint'), ('oname', 'Genevieve'), ('p', 'http://www.wikidata.org/prop/direct/P417'), ('obj', 'http://www.wikidata.org/entity/Q235863')]
# [('pname', 'shares border with'), ('oname', 'Vanves'), ('p', 'http://www.wikidata.org/prop/direct/P47'), ('obj', 'http://www.wikidata.org/entity/Q234728')]
# [('pname', 'history of topic'), ('oname', 'history of Paris'), ('p', 'http://www.wikidata.org/prop/direct/P2184'), ('obj', 'http://www.wikidata.org/entity/Q845625')]
# [('pname', 'owner of'), ('oname', 'Alexander II'), ('p', 'http://www.wikidata.org/prop/direct/P1830'), ('obj', 'http://www.wikidata.org/entity/Q24575431')]
# [('pname', 'located in or next to body of water'), ('oname', 'Seine'), ('p', 'http://www.wikidata.org/prop/direct/P206'), ('obj', 'http://www.wikidata.org/entity/Q1471')]
# [('pname', 'contains administrative territorial entity'), ('oname', '12th arrondissement of Paris'), ('p', 'http://www.wikidata.org/prop/direct/P150'), ('obj', 'http://www.wikidata.org/entity/Q171689')]
# [('pname', 'shares border with'), ('oname', 'Ivry-sur-Seine'), ('p', 'http://www.wikidata.org/prop/direct/P47'), ('obj', 'http://www.wikidata.org/entity/Q193877')]
# [('pname', 'diocese'), ('oname', 'Roman Catholic Archdiocese of Paris'), ('p', 'http://www.wikidata.org/prop/direct/P708'), ('obj', 'http://www.wikidata.org/entity/Q1242250')]
# [('pname', 'contains administrative territorial entity'), ('oname', '18th arrondissement of Paris'), ('p', 'http://www.wikidata.org/prop/direct/P150'), ('obj', 'http://www.wikidata.org/entity/Q200126')]
# [('pname', 'shares border with'), ('oname', 'Nogent-sur-Marne'), ('p', 'http://www.wikidata.org/prop/direct/P47'), ('obj', 'http://www.wikidata.org/entity/Q212274')]
# [('pname', 'significant event'), ('oname', 'Paris Commune'), ('p', 'http://www.wikidata.org/prop/direct/P793'), ('obj', 'http://www.wikidata.org/entity/Q133132')]
# [('pname', 'contains administrative territorial entity'), ('oname', '1st arrondissement of Paris'), ('p', 'http://www.wikidata.org/prop/direct/P150'), ('obj', 'http://www.wikidata.org/entity/Q161741')]
# [('pname', 'shares border with'), ('oname', 'Montrouge'), ('p', 'http://www.wikidata.org/prop/direct/P47'), ('obj', 'http://www.wikidata.org/entity/Q241021')]
# [('pname', 'shares border with'), ('oname', 'Gentilly'), ('p', 'http://www.wikidata.org/prop/direct/P47'), ('obj', 'http://www.wikidata.org/entity/Q640102')]
# [('pname', 'contains administrative territorial entity'), ('oname', '15th arrondissement of Paris'), ('p', 'http://www.wikidata.org/prop/direct/P150'), ('obj', 'http://www.wikidata.org/entity/Q191066')]
# [('pname', 'contains administrative territorial entity'), ('oname', '2nd arrondissement of Paris'), ('p', 'http://www.wikidata.org/prop/direct/P150'), ('obj', 'http://www.wikidata.org/entity/Q209549')]
# [('pname', 'award received'), ('oname', 'Companion of the Liberation'), ('p', 'http://www.wikidata.org/prop/direct/P166'), ('obj', 'http://www.wikidata.org/entity/Q2990283')]
# [('pname', 'located in or next to body of water'), ('oname', "Canal de l'Ourcq"), ('p', 'http://www.wikidata.org/prop/direct/P206'), ('obj', 'http://www.wikidata.org/entity/Q1032646')]
# [('pname', 'contains administrative territorial entity'), ('oname', '11th arrondissement of Paris'), ('p', 'http://www.wikidata.org/prop/direct/P150'), ('obj', 'http://www.wikidata.org/entity/Q169293')]
# [('pname', 'shares border with'), ('oname', 'Saint-Cloud'), ('p', 'http://www.wikidata.org/prop/direct/P47'), ('obj', 'http://www.wikidata.org/entity/Q189153')]
# [('pname', 'contains administrative territorial entity'), ('oname', '3rd arrondissement of Paris'), ('p', 'http://www.wikidata.org/prop/direct/P150'), ('obj', 'http://www.wikidata.org/entity/Q223140')]
# [('pname', 'contains administrative territorial entity'), ('oname', '4th arrondissement of Paris'), ('p', 'http://www.wikidata.org/prop/direct/P150'), ('obj', 'http://www.wikidata.org/entity/Q230127')]
# [('pname', 'drainage basin'), ('oname', 'Seine basin'), ('p', 'http://www.wikidata.org/prop/direct/P4614'), ('obj', 'http://www.wikidata.org/entity/Q2887515')]
# [('pname', 'significant event'), ('oname', 'Siege of Paris'), ('p', 'http://www.wikidata.org/prop/direct/P793'), ('obj', 'http://www.wikidata.org/entity/Q815192')]
# [('pname', 'shares border with'), ('oname', 'Joinville-le-Pont'), ('p', 'http://www.wikidata.org/prop/direct/P47'), ('obj', 'http://www.wikidata.org/entity/Q609134')]
# [('pname', 'owner of'), ('oname', 'La Sainte Catherine'), ('p', 'http://www.wikidata.org/prop/direct/P1830'), ('obj', 'http://www.wikidata.org/entity/Q3212678')]
# [('pname', 'owner of'), ('oname', 'Paris Bourse'), ('p', 'http://www.wikidata.org/prop/direct/P1830'), ('obj', 'http://www.wikidata.org/entity/Q178513')]
# [('pname', 'significant event'), ('oname', 'Siege of Paris'), ('p', 'http://www.wikidata.org/prop/direct/P793'), ('obj', 'http://www.wikidata.org/entity/Q3485975')]
# [('pname', 'significant event'), ('oname', 'Siege of Paris'), ('p', 'http://www.wikidata.org/prop/direct/P793'), ('obj', 'http://www.wikidata.org/entity/Q3485976')]
# [('pname', 'significant event'), ('oname', 'Siege of Paris'), ('p', 'http://www.wikidata.org/prop/direct/P793'), ('obj', 'http://www.wikidata.org/entity/Q3485977')]
# [('pname', 'significant event'), ('oname', 'Siege of Paris'), ('p', 'http://www.wikidata.org/prop/direct/P793'), ('obj', 'http://www.wikidata.org/entity/Q3485978')]
# [('pname', 'significant event'), ('oname', 'Siege of Paris'), ('p', 'http://www.wikidata.org/prop/direct/P793'), ('obj', 'http://www.wikidata.org/entity/Q3485979')]
# [('pname', 'significant event'), ('oname', 'Siege of Paris'), ('p', 'http://www.wikidata.org/prop/direct/P793'), ('obj', 'http://www.wikidata.org/entity/Q3485982')]
# [('pname', 'significant event'), ('oname', 'Siege of Paris'), ('p', 'http://www.wikidata.org/prop/direct/P793'), ('obj', 'http://www.wikidata.org/entity/Q3485983')]
# [('pname', 'significant event'), ('oname', 'Siege of Paris'), ('p', 'http://www.wikidata.org/prop/direct/P793'), ('obj', 'http://www.wikidata.org/entity/Q3485984')]
# [('pname', 'significant event'), ('oname', 'Siege of Paris'), ('p', 'http://www.wikidata.org/prop/direct/P793'), ('obj', 'http://www.wikidata.org/entity/Q3485985')]
# [('pname', 'significant event'), ('oname', 'Siege of Paris'), ('p', 'http://www.wikidata.org/prop/direct/P793'), ('obj', 'http://www.wikidata.org/entity/Q3485986')]
# [('pname', 'significant event'), ('oname', 'Siege of Paris'), ('p', 'http://www.wikidata.org/prop/direct/P793'), ('obj', 'http://www.wikidata.org/entity/Q3485987')]
# [('pname', 'head of government'), ('oname', 'Anne Hidalgo'), ('p', 'http://www.wikidata.org/prop/direct/P6'), ('obj', 'http://www.wikidata.org/entity/Q2851133')]
# [('pname', 'legislative body'), ('oname', 'Council of Paris'), ('p', 'http://www.wikidata.org/prop/direct/P194'), ('obj', 'http://www.wikidata.org/entity/Q775994')]
# [('pname', 'has parts of the class'), ('oname', 'municipal arrondissement of Paris'), ('p', 'http://www.wikidata.org/prop/direct/P2670'), ('obj', 'http://www.wikidata.org/entity/Q679388')]
# [('pname', 'owner of'), ('oname', 'Parc des Princes'), ('p', 'http://www.wikidata.org/prop/direct/P1830'), ('obj', 'http://www.wikidata.org/entity/Q193431')]
# [('pname', 'shares border with'), ('oname', 'Fontenay-sous-Bois'), ('p', 'http://www.wikidata.org/prop/direct/P47'), ('obj', 'http://www.wikidata.org/entity/Q193899')]
# [('pname', 'owner of'), ('oname', 'Stade Jean-Bouin'), ('p', 'http://www.wikidata.org/prop/direct/P1830'), ('obj', 'http://www.wikidata.org/entity/Q670499')]
# [('pname', 'category for films shot at this location'), ('oname', 'Category:Films shot in Paris'), ('p', 'http://www.wikidata.org/prop/direct/P1740'), ('obj', 'http://www.wikidata.org/entity/Q8458184')]
# [('pname', 'different from'), ('oname', 'Paryż'), ('p', 'http://www.wikidata.org/prop/direct/P1889'), ('obj', 'http://www.wikidata.org/entity/Q11813144')]
# [('pname', 'owner of'), ('oname', 'The Sleepers'), ('p', 'http://www.wikidata.org/prop/direct/P1830'), ('obj', 'http://www.wikidata.org/entity/Q326503')]
# [('pname', 'named after'), ('oname', 'Parisii'), ('p', 'http://www.wikidata.org/prop/direct/P138'), ('obj', 'http://www.wikidata.org/entity/Q656902')]
# [('pname', "topic's main category"), ('oname', 'Category:Paris'), ('p', 'http://www.wikidata.org/prop/direct/P910'), ('obj', 'http://www.wikidata.org/entity/Q5626403')]
# [('pname', 'owner of'), ('oname', 'Hôtel de Chalon-Luxembourg'), ('p', 'http://www.wikidata.org/prop/direct/P1830'), ('obj', 'http://www.wikidata.org/entity/Q369234')]
# [('pname', 'owner of'), ('oname', 'La Fraternité'), ('p', 'http://www.wikidata.org/prop/direct/P1830'), ('obj', 'http://www.wikidata.org/entity/Q15921401')]
# [('pname', 'instance of'), ('oname', 'territorial collectivity of France with special status'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('obj', 'http://www.wikidata.org/entity/Q22923920')]
# [('pname', 'activity policy in this place'), ('oname', 'do not feed the animals'), ('p', 'http://www.wikidata.org/prop/direct/P5023'), ('obj', 'http://www.wikidata.org/entity/Q5286412')]
# [('pname', 'list of monuments'), ('oname', 'list of historic monuments in Paris'), ('p', 'http://www.wikidata.org/prop/direct/P1456'), ('obj', 'http://www.wikidata.org/entity/Q3252156')]
# [('pname', 'district heating grid'), ('oname', 'réseau de chaleur urbain CPCU'), ('p', 'http://www.wikidata.org/prop/direct/P9611'), ('obj', 'http://www.wikidata.org/entity/Q105687036')]
# [('pname', 'owner of'), ('oname', "Pavillon d'Armenonville"), ('p', 'http://www.wikidata.org/prop/direct/P1830'), ('obj', 'http://www.wikidata.org/entity/Q18086668')]
# [('pname', 'located in or next to body of water'), ('oname', 'bassin de la Villette'), ('p', 'http://www.wikidata.org/prop/direct/P206'), ('obj', 'http://www.wikidata.org/entity/Q810526')]
# [('pname', 'economy of topic'), ('oname', 'economy of Paris'), ('p', 'http://www.wikidata.org/prop/direct/P8744'), ('obj', 'http://www.wikidata.org/entity/Q5333743')]
# [('pname', 'demographics of topic'), ('oname', 'demographics of Paris'), ('p', 'http://www.wikidata.org/prop/direct/P9241'), ('obj', 'http://www.wikidata.org/entity/Q2246902')]
# [('pname', 'owner of'), ('oname', 'Jacob Wrestling with the Angel'), ('p', 'http://www.wikidata.org/prop/direct/P1830'), ('obj', 'http://www.wikidata.org/entity/Q3837491')]
# [('pname', 'category for people who died here'), ('oname', 'Category:Deaths in Paris'), ('p', 'http://www.wikidata.org/prop/direct/P1465'), ('obj', 'http://www.wikidata.org/entity/Q9846779')]
# [('pname', 'coat of arms'), ('oname', 'coat of arms of Paris'), ('p', 'http://www.wikidata.org/prop/direct/P237'), ('obj', 'http://www.wikidata.org/entity/Q1925366')]
# [('pname', 'list of monuments'), ('oname', 'list of monuments and sites in Paris'), ('p', 'http://www.wikidata.org/prop/direct/P1456'), ('obj', 'http://www.wikidata.org/entity/Q1403319')]
# [('pname', 'owner of'), ('oname', 'Grand Synagogue of Paris'), ('p', 'http://www.wikidata.org/prop/direct/P1830'), ('obj', 'http://www.wikidata.org/entity/Q1358886')]
# [('pname', 'owner of'), ('oname', 'fontaine de Jarente'), ('p', 'http://www.wikidata.org/prop/direct/P1830'), ('obj', 'http://www.wikidata.org/entity/Q1435786')]
# [('pname', 'highest point'), ('oname', 'highest point of Paris'), ('p', 'http://www.wikidata.org/prop/direct/P610'), ('obj', 'http://www.wikidata.org/entity/Q1440664')]
# [('pname', 'owner of'), ('oname', 'Belleville funicular tramway'), ('p', 'http://www.wikidata.org/prop/direct/P1830'), ('obj', 'http://www.wikidata.org/entity/Q1524643')]
# [('pname', 'owner of'), ('oname', 'La Famille'), ('p', 'http://www.wikidata.org/prop/direct/P1830'), ('obj', 'http://www.wikidata.org/entity/Q15921385')]
# [('pname', "topic's main template"), ('oname', 'Template:Paris'), ('p', 'http://www.wikidata.org/prop/direct/P1424'), ('obj', 'http://www.wikidata.org/entity/Q18220037')]
# [('pname', 'category for maps'), ('oname', 'Category:Maps of Paris'), ('p', 'http://www.wikidata.org/prop/direct/P7867'), ('obj', 'http://www.wikidata.org/entity/Q18668319')]
# [('pname', 'foods traditionally associated'), ('oname', 'Parisian cuisine'), ('p', 'http://www.wikidata.org/prop/direct/P868'), ('obj', 'http://www.wikidata.org/entity/Q21129738')]
# [('pname', 'legal form'), ('oname', 'commune of France with specific status'), ('p', 'http://www.wikidata.org/prop/direct/P1454'), ('obj', 'http://www.wikidata.org/entity/Q22927616')]
# [('pname', 'owner of'), ('oname', 'pyramid of bois de Vincennes'), ('p', 'http://www.wikidata.org/prop/direct/P1830'), ('obj', 'http://www.wikidata.org/entity/Q3411287')]
# [('pname', 'flag'), ('oname', 'flag of Paris'), ('p', 'http://www.wikidata.org/prop/direct/P163'), ('obj', 'http://www.wikidata.org/entity/Q659058')]
# [('pname', 'category of people buried here'), ('oname', 'Category:Burials in Paris by place'), ('p', 'http://www.wikidata.org/prop/direct/P1791'), ('obj', 'http://www.wikidata.org/entity/Q7977477')]
# [('pname', "topic's main Wikimedia portal"), ('oname', 'Portal:Paris'), ('p', 'http://www.wikidata.org/prop/direct/P1151'), ('obj', 'http://www.wikidata.org/entity/Q8253667')]
# [('pname', 'category for people born here'), ('oname', 'Category:Births in Paris'), ('p', 'http://www.wikidata.org/prop/direct/P1464'), ('obj', 'http://www.wikidata.org/entity/Q9226347')]
# [('pname', 'open data portal'), ('oname', 'Paris Open Data'), ('p', 'http://www.wikidata.org/prop/direct/P8402'), ('obj', 'http://www.wikidata.org/entity/Q97064103')]
# [('pname', 'Vatican Library ID (former scheme)'), ('p', 'http://www.wikidata.org/prop/direct/P1017'), ('obj', 'ADV12362772')]
# [('pname', 'Dewey Decimal Classification'), ('p', 'http://www.wikidata.org/prop/direct/P1036'), ('obj', '2--44361')]
# [('pname', 'population'), ('p', 'http://www.wikidata.org/prop/direct/P1082'), ('obj', '2175601')]
# [('pname', 'U.S. National Archives Identifier'), ('p', 'http://www.wikidata.org/prop/direct/P1225'), ('obj', '10044289')]
# [('pname', 'U.S. National Archives Identifier'), ('p', 'http://www.wikidata.org/prop/direct/P1225'), ('obj', '10045153')]
# [('pname', 'OmegaWiki Defined Meaning'), ('p', 'http://www.wikidata.org/prop/direct/P1245'), ('obj', '6724')]
# [('pname', 'Gran Enciclopèdia Catalana ID'), ('p', 'http://www.wikidata.org/prop/direct/P1296'), ('obj', '0049060')]
# [('pname', 'LNB ID'), ('p', 'http://www.wikidata.org/prop/direct/P1368'), ('obj', '000042629')]
# [('pname', 'Encyclopædia Britannica Online ID'), ('p', 'http://www.wikidata.org/prop/direct/P1417'), ('obj', 'place/Paris')]
# [('pname', 'Jewish Encyclopedia ID (Russian)'), ('p', 'http://www.wikidata.org/prop/direct/P1438'), ('obj', '13151')]
# [('pname', 'nickname'), ('p', 'http://www.wikidata.org/prop/direct/P1449'), ('obj', 'The City of Light')]
# [('pname', 'female population'), ('p', 'http://www.wikidata.org/prop/direct/P1539'), ('obj', '1158623')]
# [('pname', 'male population'), ('p', 'http://www.wikidata.org/prop/direct/P1540'), ('obj', '1028903')]
# [('pname', 'demonym'), ('p', 'http://www.wikidata.org/prop/direct/P1549'), ('obj', 'Parisian')]
# [('pname', 'demonym'), ('p', 'http://www.wikidata.org/prop/direct/P1549'), ('obj', 'Parisians')]
# [('pname', 'GeoNames ID'), ('p', 'http://www.wikidata.org/prop/direct/P1566'), ('obj', '2968815')]
# [('pname', 'SIREN number'), ('p', 'http://www.wikidata.org/prop/direct/P1616'), ('obj', '217500016')]
# [('pname', 'Getty Thesaurus of Geographic Names ID'), ('p', 'http://www.wikidata.org/prop/direct/P1667'), ('obj', '7008038')]
# [('pname', 'place name sign'), ('p', 'http://www.wikidata.org/prop/direct/P1766'), ('obj', 'http://commons.wikimedia.org/wiki/Special:FilePath/Panneau%20entr%C3%A9e%20Paris%20Avenue%20Georges%20Lafenestre%20Paris%202.jpg')]
# [('pname', 'image'), ('p', 'http://www.wikidata.org/prop/direct/P18'), ('obj', 'http://commons.wikimedia.org/wiki/Special:FilePath/Paris%20-%20Eiffelturm%20und%20Marsfeld2.jpg')]
# [('pname', 'UN/LOCODE'), ('p', 'http://www.wikidata.org/prop/direct/P1937'), ('obj', 'FRPAR')]
# [('pname', 'location map'), ('p', 'http://www.wikidata.org/prop/direct/P1943'), ('obj', 'http://commons.wikimedia.org/wiki/Special:FilePath/Paris%20plan%20jms.png')]
# [('pname', 'Foursquare venue ID'), ('p', 'http://www.wikidata.org/prop/direct/P1968'), ('obj', '50dbd18d498eb594ef575b0a')]
# [('pname', 'Facebook Places ID'), ('p', 'http://www.wikidata.org/prop/direct/P1997'), ('obj', '110774245616525')]
# [('pname', 'Twitter username'), ('p', 'http://www.wikidata.org/prop/direct/P2002'), ('obj', 'Paris')]
# [('pname', 'Instagram username'), ('p', 'http://www.wikidata.org/prop/direct/P2003'), ('obj', 'paris_maville')]
# [('pname', 'Facebook ID'), ('p', 'http://www.wikidata.org/prop/direct/P2013'), ('obj', 'paris')]
# [('pname', 'elevation above sea level'), ('p', 'http://www.wikidata.org/prop/direct/P2044'), ('obj', '28')]
# [('pname', 'area'), ('p', 'http://www.wikidata.org/prop/direct/P2046'), ('obj', '105.4')]
# [('pname', 'ISNI'), ('p', 'http://www.wikidata.org/prop/direct/P213'), ('obj', '0000 0001 2114 268X')]
# [('pname', 'VIAF ID'), ('p', 'http://www.wikidata.org/prop/direct/P214'), ('obj', '158822968')]
# [('pname', 'FAST ID'), ('p', 'http://www.wikidata.org/prop/direct/P2163'), ('obj', '1205283')]
# [('pname', 'GND ID'), ('p', 'http://www.wikidata.org/prop/direct/P227'), ('obj', '4044660-8')]
# [('pname', 'GNS Unique Feature ID'), ('p', 'http://www.wikidata.org/prop/direct/P2326'), ('obj', '-1456928')]
# [('pname', 'YSO ID'), ('p', 'http://www.wikidata.org/prop/direct/P2347'), ('obj', '104996')]
# [('pname', 'IATA airport code'), ('p', 'http://www.wikidata.org/prop/direct/P238'), ('obj', 'PAR')]
# [('pname', 'Library of Congress authority ID'), ('p', 'http://www.wikidata.org/prop/direct/P244'), ('obj', 'n79058874')]
# [('pname', 'BabelNet ID'), ('p', 'http://www.wikidata.org/prop/direct/P2581'), ('obj', '00015540n')]
# [('pname', 'INSEE department code'), ('p', 'http://www.wikidata.org/prop/direct/P2586'), ('obj', '75')]
# [('pname', 'Bibliothèque nationale de France ID'), ('p', 'http://www.wikidata.org/prop/direct/P268'), ('obj', '11865278m')]
# [('pname', 'Bibliothèque nationale de France ID'), ('p', 'http://www.wikidata.org/prop/direct/P268'), ('obj', '152821567')]
# [('pname', 'IdRef ID'), ('p', 'http://www.wikidata.org/prop/direct/P269'), ('obj', '026397765')]
# [('pname', 'postal code'), ('p', 'http://www.wikidata.org/prop/direct/P281'), ('obj', '75010')]
# [('pname', 'postal code'), ('p', 'http://www.wikidata.org/prop/direct/P281'), ('obj', '75020')]
# [('pname', 'postal code'), ('p', 'http://www.wikidata.org/prop/direct/P281'), ('obj', '75005')]
# [('pname', 'postal code'), ('p', 'http://www.wikidata.org/prop/direct/P281'), ('obj', '75019')]
# [('pname', 'postal code'), ('p', 'http://www.wikidata.org/prop/direct/P281'), ('obj', '75013')]
# [('pname', 'postal code'), ('p', 'http://www.wikidata.org/prop/direct/P281'), ('obj', '75003')]
# [('pname', 'postal code'), ('p', 'http://www.wikidata.org/prop/direct/P281'), ('obj', '75007')]
# [('pname', 'postal code'), ('p', 'http://www.wikidata.org/prop/direct/P281'), ('obj', '75008')]
# [('pname', 'postal code'), ('p', 'http://www.wikidata.org/prop/direct/P281'), ('obj', '75016')]
# [('pname', 'postal code'), ('p', 'http://www.wikidata.org/prop/direct/P281'), ('obj', '75017')]
# [('pname', 'postal code'), ('p', 'http://www.wikidata.org/prop/direct/P281'), ('obj', '75014')]
# [('pname', 'postal code'), ('p', 'http://www.wikidata.org/prop/direct/P281'), ('obj', '75116')]
# [('pname', 'postal code'), ('p', 'http://www.wikidata.org/prop/direct/P281'), ('obj', '75015')]
# [('pname', 'postal code'), ('p', 'http://www.wikidata.org/prop/direct/P281'), ('obj', '75018')]
# [('pname', 'postal code'), ('p', 'http://www.wikidata.org/prop/direct/P281'), ('obj', '75009')]
# [('pname', 'postal code'), ('p', 'http://www.wikidata.org/prop/direct/P281'), ('obj', '75006')]
# [('pname', 'postal code'), ('p', 'http://www.wikidata.org/prop/direct/P281'), ('obj', '75012')]
# [('pname', 'postal code'), ('p', 'http://www.wikidata.org/prop/direct/P281'), ('obj', '75001')]
# [('pname', 'postal code'), ('p', 'http://www.wikidata.org/prop/direct/P281'), ('obj', '75004')]
# [('pname', 'postal code'), ('p', 'http://www.wikidata.org/prop/direct/P281'), ('obj', '75011')]
# [('pname', 'postal code'), ('p', 'http://www.wikidata.org/prop/direct/P281'), ('obj', '75002')]
# [('pname', 'Great Russian Encyclopedia Online ID'), ('p', 'http://www.wikidata.org/prop/direct/P2924'), ('obj', '2320508')]
# [('pname', 'Nomisma ID'), ('p', 'http://www.wikidata.org/prop/direct/P2950'), ('obj', 'paris')]
# [('pname', 'ISO 3166-2 code'), ('p', 'http://www.wikidata.org/prop/direct/P300'), ('obj', 'FR-75')]
# [('pname', 'Guardian topic ID'), ('p', 'http://www.wikidata.org/prop/direct/P3106'), ('obj', 'world/paris')]
# [('pname', 'Encyclopædia Universalis ID'), ('p', 'http://www.wikidata.org/prop/direct/P3219'), ('obj', 'paris')]
# [('pname', 'NE.se ID'), ('p', 'http://www.wikidata.org/prop/direct/P3222'), ('obj', 'paris')]
# [('pname', 'NE.se ID'), ('p', 'http://www.wikidata.org/prop/direct/P3222'), ('obj', 'paris-(departement-frankrike)')]
# [('pname', 'Treccani ID'), ('p', 'http://www.wikidata.org/prop/direct/P3365'), ('obj', 'parigi')]
# [('pname', 'Quora topic ID'), ('p', 'http://www.wikidata.org/prop/direct/P3417'), ('obj', 'Paris')]
# [('pname', 'nighttime view'), ('p', 'http://www.wikidata.org/prop/direct/P3451'), ('obj', 'http://commons.wikimedia.org/wiki/Special:FilePath/Eiffel%20Tower%20from%20the%20Tour%20Montparnasse%2C%201%20May%202012%20N2.jpg')]
# [('pname', 'National Diet Library ID'), ('p', 'http://www.wikidata.org/prop/direct/P349'), ('obj', '00629026')]
# [('pname', 'Ringgold ID'), ('p', 'http://www.wikidata.org/prop/direct/P3500'), ('obj', '55653')]
# [('pname', 'Zhihu topic ID'), ('p', 'http://www.wikidata.org/prop/direct/P3553'), ('obj', '19566221')]
# [('pname', 'EU VAT number'), ('p', 'http://www.wikidata.org/prop/direct/P3608'), ('obj', 'FR72217500016')]
# [('pname', 'Commons category'), ('p', 'http://www.wikidata.org/prop/direct/P373'), ('obj', 'Paris')]
# [('pname', 'INSEE municipality code'), ('p', 'http://www.wikidata.org/prop/direct/P374'), ('obj', '75056')]
# [('pname', 'Google Maps Customer ID'), ('p', 'http://www.wikidata.org/prop/direct/P3749'), ('obj', '291470376679806048')]
# [('pname', 'geoshape'), ('p', 'http://www.wikidata.org/prop/direct/P3896'), ('obj', 'http://commons.wikimedia.org/data/main/Data:Paris.map')]
# [('pname', 'licence plate code'), ('p', 'http://www.wikidata.org/prop/direct/P395'), ('obj', '75')]
# [('pname', 'subreddit'), ('p', 'http://www.wikidata.org/prop/direct/P3984'), ('obj', 'paris')]
# [('pname', 'OpenStreetMap relation ID'), ('p', 'http://www.wikidata.org/prop/direct/P402'), ('obj', '7444')]
# [('pname', 'flag image'), ('p', 'http://www.wikidata.org/prop/direct/P41'), ('obj', 'http://commons.wikimedia.org/wiki/Special:FilePath/Flag%20of%20Paris%20with%20coat%20of%20arms.svg')]
# [('pname', 'Instagram location ID'), ('p', 'http://www.wikidata.org/prop/direct/P4173'), ('obj', '6889842')]
# [('pname', 'LinkedIn company ID'), ('p', 'http://www.wikidata.org/prop/direct/P4264'), ('obj', 'villedeparis')]
# [('pname', 'Store norske leksikon ID'), ('p', 'http://www.wikidata.org/prop/direct/P4342'), ('obj', 'Paris')]
# [('pname', 'pronunciation audio'), ('p', 'http://www.wikidata.org/prop/direct/P443'), ('obj', 'http://commons.wikimedia.org/wiki/Special:FilePath/LL-Q150%20%28fra%29-Ash%20Crow-Paris.wav')]
# [('pname', 'pronunciation audio'), ('p', 'http://www.wikidata.org/prop/direct/P443'), ('obj', 'http://commons.wikimedia.org/wiki/Special:FilePath/Lb-Par%C3%A4is.ogg')]
# [('pname', 'UK Parliament thesaurus ID'), ('p', 'http://www.wikidata.org/prop/direct/P4527'), ('obj', '95293')]
# [('pname', 'EMLO location ID'), ('p', 'http://www.wikidata.org/prop/direct/P4672'), ('obj', '0d3cfe92-75a3-4ec3-b66e-3243ba783b6d')]
# [('pname', 'EMLO location ID'), ('p', 'http://www.wikidata.org/prop/direct/P4672'), ('obj', '8c11005d-9007-4839-b35e-f7fe1cedc116')]
# [('pname', 'EMLO location ID'), ('p', 'http://www.wikidata.org/prop/direct/P4672'), ('obj', 'ea30d147-7f3c-4765-89b7-a6e9aadbe7b6')]
# [('pname', 'EMLO location ID'), ('p', 'http://www.wikidata.org/prop/direct/P4672'), ('obj', 'eb878cf5-18a7-4065-aa31-2a0d53644174')]
# [('pname', 'EMLO location ID'), ('p', 'http://www.wikidata.org/prop/direct/P4672'), ('obj', 'efc0401b-db62-4c7d-a6e0-dc1fe0181ee1')]
# [('pname', 'local dialing code'), ('p', 'http://www.wikidata.org/prop/direct/P473'), ('obj', '1')]
# [('pname', 'MeSH descriptor ID'), ('p', 'http://www.wikidata.org/prop/direct/P486'), ('obj', 'D010297')]
# [('pname', 'Brockhaus Enzyklopädie online ID'), ('p', 'http://www.wikidata.org/prop/direct/P5019'), ('obj', 'paris-40')]
# [('pname', 'Interlingual Index ID'), ('p', 'http://www.wikidata.org/prop/direct/P5063'), ('obj', 'i83645')]
# [('pname', 'Giant Bomb ID'), ('p', 'http://www.wikidata.org/prop/direct/P5247'), ('obj', '3035-487')]
# [('pname', 'setlist.fm venue ID'), ('p', 'http://www.wikidata.org/prop/direct/P5432'), ('obj', '6bd40a46')]
# [('pname', 'Courrier international topic ID'), ('p', 'http://www.wikidata.org/prop/direct/P5551'), ('obj', 'paris')]
# [('pname', 'archINFORM location ID'), ('p', 'http://www.wikidata.org/prop/direct/P5573'), ('obj', '585')]
# [('pname', 'inception'), ('p', 'http://www.wikidata.org/prop/direct/P571'), ('obj', '-300-01-01T00:00:00Z')]
# [('pname', 'EU Research participant ID'), ('p', 'http://www.wikidata.org/prop/direct/P5785'), ('obj', '998498504')]
# [('pname', 'Gynopedia ID'), ('p', 'http://www.wikidata.org/prop/direct/P5843'), ('obj', 'Paris')]
# [('pname', 'Comic Vine ID'), ('p', 'http://www.wikidata.org/prop/direct/P5905'), ('obj', '4020-56052')]
# [('pname', 'annual number of weddings'), ('p', 'http://www.wikidata.org/prop/direct/P5982'), ('obj', '9021')]
# [('pname', 'NUTS code'), ('p', 'http://www.wikidata.org/prop/direct/P605'), ('obj', 'FR101')]
# [('pname', 'Larousse ID'), ('p', 'http://www.wikidata.org/prop/direct/P6058'), ('obj', 'ville/wd/137068')]
# [('pname', 'BBC News topic ID'), ('p', 'http://www.wikidata.org/prop/direct/P6200'), ('obj', 'cxw7q5zm562t')]
# [('pname', 'Fandom article ID'), ('p', 'http://www.wikidata.org/prop/direct/P6262'), ('obj', 'cities:Paris')]
# [('pname', 'Fandom article ID'), ('p', 'http://www.wikidata.org/prop/direct/P6262'), ('obj', 'france:Paris')]
# [('pname', 'YSA ID'), ('p', 'http://www.wikidata.org/prop/direct/P6293'), ('obj', 'Y104996')]
# [('pname', 'Krugosvet article'), ('p', 'http://www.wikidata.org/prop/direct/P6385'), ('obj', 'Earth_sciences/geografiya/PARIZH.html')]
# [('pname', "Treccani's Dizionario di Storia ID"), ('p', 'http://www.wikidata.org/prop/direct/P6404'), ('obj', 'parigi')]
# [('pname', 'Freebase ID'), ('p', 'http://www.wikidata.org/prop/direct/P646'), ('obj', '/m/05qtj')]
# [('pname', 'Klexikon article ID'), ('p', 'http://www.wikidata.org/prop/direct/P6573'), ('obj', 'Paris')]
# [('pname', 'Japan Search name ID'), ('p', 'http://www.wikidata.org/prop/direct/P6698'), ('obj', 'パリ')]
# [('pname', 'De Agostini ID'), ('p', 'http://www.wikidata.org/prop/direct/P6706'), ('obj', 'Parigi')]
# [('pname', "Who's on First ID"), ('p', 'http://www.wikidata.org/prop/direct/P6766'), ('obj', '85683497')]
# [('pname', 'HAL structure ID'), ('p', 'http://www.wikidata.org/prop/direct/P6773'), ('obj', '460091')]
# [('pname', 'Uppsala University Alvin ID'), ('p', 'http://www.wikidata.org/prop/direct/P6821'), ('obj', 'alvin-place:676')]
# [('pname', 'NicoNicoPedia ID'), ('p', 'http://www.wikidata.org/prop/direct/P6900'), ('obj', 'パリ')]
# [('pname', 'NKCR AUT ID'), ('p', 'http://www.wikidata.org/prop/direct/P691'), ('obj', 'ge130380')]
# [('pname', 'Hungarian National Namespace place ID'), ('p', 'http://www.wikidata.org/prop/direct/P6987'), ('obj', '197469')]
# [('pname', 'OpenWeatherMap city ID'), ('p', 'http://www.wikidata.org/prop/direct/P7197'), ('obj', '2988507')]
# [('pname', 'OpenWeatherMap city ID'), ('p', 'http://www.wikidata.org/prop/direct/P7197'), ('obj', '2988506')]
# [('pname', 'iNaturalist place ID'), ('p', 'http://www.wikidata.org/prop/direct/P7471'), ('obj', '99545')]
# [('pname', 'Visuotinė lietuvių enciklopedija ID'), ('p', 'http://www.wikidata.org/prop/direct/P7666'), ('obj', 'paryzius')]
# [('pname', 'French Vikidia ID'), ('p', 'http://www.wikidata.org/prop/direct/P7818'), ('obj', 'Paris')]
# [('pname', 'Italian Vikidia ID'), ('p', 'http://www.wikidata.org/prop/direct/P7822'), ('obj', 'Parigi')]
# [('pname', 'Spanish Vikidia ID'), ('p', 'http://www.wikidata.org/prop/direct/P7827'), ('obj', 'París')]
# [('pname', 'English Vikidia ID'), ('p', 'http://www.wikidata.org/prop/direct/P7829'), ('obj', 'Paris')]
# [('pname', 'Basque Vikidia ID'), ('p', 'http://www.wikidata.org/prop/direct/P7832'), ('obj', 'Paris')]
# [('pname', 'Joconde location ID'), ('p', 'http://www.wikidata.org/prop/direct/P7850'), ('obj', 'T84-2769')]
# [('pname', 'WorldCat Identities ID'), ('p', 'http://www.wikidata.org/prop/direct/P7859'), ('obj', 'lccn-n85206229')]
# [('pname', 'Analysis & Policy Observatory term ID'), ('p', 'http://www.wikidata.org/prop/direct/P7870'), ('obj', '11005')]
# [('pname', 'Joconde discovery ID'), ('p', 'http://www.wikidata.org/prop/direct/P7960'), ('obj', 'T115-1966')]
# [('pname', 'HASC'), ('p', 'http://www.wikidata.org/prop/direct/P8119'), ('obj', 'FR.IF.VP')]
# [('pname', 'FactGrid item ID'), ('p', 'http://www.wikidata.org/prop/direct/P8168'), ('obj', 'Q10441')]
# [('pname', 'iDAI.gazetteer ID'), ('p', 'http://www.wikidata.org/prop/direct/P8217'), ('obj', '2081915')]
# [('pname', 'Yle topic ID'), ('p', 'http://www.wikidata.org/prop/direct/P8309'), ('obj', '18-196013')]
# [('pname', 'Grove Art Online ID'), ('p', 'http://www.wikidata.org/prop/direct/P8406'), ('obj', 'T065354')]
# [('pname', 'KBpedia ID'), ('p', 'http://www.wikidata.org/prop/direct/P8408'), ('obj', 'Paris')]
# [('pname', 'EHESS ID of a French commune'), ('p', 'http://www.wikidata.org/prop/direct/P8422'), ('obj', '26207')]
# [('pname', 'RKD thesaurus ID'), ('p', 'http://www.wikidata.org/prop/direct/P8519'), ('obj', '129')]
# [('pname', 'official website'), ('p', 'http://www.wikidata.org/prop/direct/P856'), ('obj', 'https://www.paris.fr/')]
# [('pname', 'Jewish Encyclopedia ID'), ('p', 'http://www.wikidata.org/prop/direct/P8590'), ('obj', '11912')]
# [('pname', 'aerial view'), ('p', 'http://www.wikidata.org/prop/direct/P8592'), ('obj', 'http://commons.wikimedia.org/wiki/Special:FilePath/Paris%20-%20Orthophotographie%20-%202018.jpg')]
# [('pname', 'social media followers'), ('p', 'http://www.wikidata.org/prop/direct/P8687'), ('obj', '2127845')]
# [('pname', 'GADM ID'), ('p', 'http://www.wikidata.org/prop/direct/P8714'), ('obj', 'FRA.8.3_1')]
# [('pname', 'WordNet 3.1 Synset ID'), ('p', 'http://www.wikidata.org/prop/direct/P8814'), ('obj', '08952341-n')]
# [('pname', 'Namuwiki ID'), ('p', 'http://www.wikidata.org/prop/direct/P8885'), ('obj', '파리(프랑스)')]
# [('pname', 'Swedish National Library Arken ID'), ('p', 'http://www.wikidata.org/prop/direct/P8899'), ('obj', 'Paris')]
# [('pname', 'SAPA ID'), ('p', 'http://www.wikidata.org/prop/direct/P8974'), ('obj', 'p/b38adfac-e177-4289-bcbb-a849d21eaef9')]
# [('pname', 'HDS ID'), ('p', 'http://www.wikidata.org/prop/direct/P902'), ('obj', '006604')]
# [('pname', 'BHCL UUID'), ('p', 'http://www.wikidata.org/prop/direct/P9037'), ('obj', '07a5cd50-bb17-4948-8b4d-eb37e47c0750')]
# [('pname', 'BHCL UUID'), ('p', 'http://www.wikidata.org/prop/direct/P9037'), ('obj', '165885fa-ad09-4f0f-adbc-6500b639222d')]
# [('pname', 'GitHub topic'), ('p', 'http://www.wikidata.org/prop/direct/P9100'), ('obj', 'paris')]
# [('pname', 'Provenio UUID'), ('p', 'http://www.wikidata.org/prop/direct/P9223'), ('obj', '0826d055-7b01-4153-bd3f-f50b19163e57')]
# [('pname', 'Provenio UUID'), ('p', 'http://www.wikidata.org/prop/direct/P9223'), ('obj', '856a5774-8a28-4200-8e8f-f540d4c34431')]
# [('pname', 'AIATSIS Place Thesaurus ID'), ('p', 'http://www.wikidata.org/prop/direct/P9293'), ('obj', '4973')]
# [('pname', 'Ávvir topic ID'), ('p', 'http://www.wikidata.org/prop/direct/P9318'), ('obj', 'paris')]
# [('pname', 'France24 topic ID (French)'), ('p', 'http://www.wikidata.org/prop/direct/P9346'), ('obj', 'paris')]
# [('pname', 'Commons gallery'), ('p', 'http://www.wikidata.org/prop/direct/P935'), ('obj', 'Paris')]
# [('pname', 'CNA topic ID'), ('p', 'http://www.wikidata.org/prop/direct/P9368'), ('obj', 'paris')]
# [('pname', 'coat of arms image'), ('p', 'http://www.wikidata.org/prop/direct/P94'), ('obj', 'http://commons.wikimedia.org/wiki/Special:FilePath/Grandes%20Armes%20de%20Paris.svg')]
# [('pname', 'page banner'), ('p', 'http://www.wikidata.org/prop/direct/P948'), ('obj', 'http://commons.wikimedia.org/wiki/Special:FilePath/Paris%20banner.jpg')]
# [('pname', 'Biblioteca Nacional de España ID'), ('p', 'http://www.wikidata.org/prop/direct/P950'), ('obj', 'XX451222')]
# [('pname', 'Encyclopedia of China Online Database ID'), ('p', 'http://www.wikidata.org/prop/direct/P9545'), ('obj', '191897')]
# [('pname', 'Armeniapedia ID'), ('p', 'http://www.wikidata.org/prop/direct/P9629'), ('obj', '4309')]
# [('pname', 'Schoenberg Database of Manuscripts place ID'), ('p', 'http://www.wikidata.org/prop/direct/P9757'), ('obj', '1')]
# [('pname', 'MusicBrainz area ID'), ('p', 'http://www.wikidata.org/prop/direct/P982'), ('obj', 'dc10c22b-e510-4006-8b7f-fecb4f36436e')]
# [('pname', 'Curlie ID'), ('p', 'http://www.wikidata.org/prop/direct/P998'), ('obj', 'World/Français/Régional/Europe/France/Régions/Ile-de-France/Paris/')]
# [('pname', 'Thomas Jefferson Encyclopedia ID'), ('p', 'http://www.wikidata.org/prop/direct/P8630'), ('obj', 'paris')]
# 327

# %% [markdown]
# #### Comment
# And so we have the country property to retrieve were a place is located:
#
# | IRI           | Description   | Role      |
# | -----------   | -----------   |-----------|
# | `wdt:P17`   | country   | predicate |
#
# And so starting from a place or a city we have have the BGP to find the belonging country:
#
# ```
# ?loc wdt:P17 ?country
# ```

# %% [markdown]
# ## Task 3
# 3. How many poets and writers  have a place of birth, death, or burial in Germany and France?

# %% [markdown]
# We start from the given URIs:
#
# | IRI           | Description   | Role      |
# | -----------   | -----------   |-----------|
# | `wd:Q183`     | Germany       | node |
# | `wd:Q142`     | France        | node |
# | `wd:Q49757`     | poet        | node |
# | `wd:Q36180`     | writer        | node |
#
# I'm going to use the wdt:P17 "country" property to locate a place

# %%
#Number of poets and writers with place of birth or place of death or place of burial located in France 
queryString = """
SELECT (COUNT(DISTINCT ?wname) AS ?num)
WHERE { 

# ?per wdt:P106 ?job ;
    # ?p ?obj .
# ?obj wdt:P17 ?c .

FILTER(?job = wd:Q36180 || ?job = wd:Q49757).
FILTER(?p = wdt:P19 || ?p = wdt:P20 || ?p = wdt:P119).
FILTER(?c = wd:Q142).

# ?per <http://schema.org/name> ?wname.
#?p <http://schema.org/name> ?pname .
#?obj <http://schema.org/name> ?oname .
#?c <http://schema.org/name> ?cname .
}
#GROUP BY ?wname ?cname
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('num', '15788')]
# 1

# %%
#Number of poets and writers with place of birth or place of death or place of burial located in Germany
queryString = """
SELECT (COUNT(DISTINCT ?wname) AS ?num)
WHERE { 

# ?per wdt:P106 ?job ;
    # ?p ?obj .
# ?obj wdt:P17 ?c .

FILTER(?job = wd:Q36180 || ?job = wd:Q49757).
FILTER(?p = wdt:P19 || ?p = wdt:P20 || ?p = wdt:P119).
FILTER(?c = wd:Q183).

# ?per <http://schema.org/name> ?wname.
#?p <http://schema.org/name> ?pname .
#?obj <http://schema.org/name> ?oname .
#?c <http://schema.org/name> ?cname .
}
#GROUP BY ?wname ?cname
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('num', '26782')]
# 1

# %%
#Number of poets and writers with place of birth or place of death or place of burial located in Frnce or Germany
queryString = """
SELECT (COUNT(DISTINCT ?wname) AS ?num)
WHERE { 

# ?per wdt:P106 ?job ;
    # ?p ?obj .
# ?obj wdt:P17 ?c .

FILTER(?job = wd:Q36180 || ?job = wd:Q49757).
FILTER(?p = wdt:P19 || ?p = wdt:P20 || ?p = wdt:P119).
FILTER(?c = wd:Q142 || ?c = wd:Q183).

# ?per <http://schema.org/name> ?wname.
#?p <http://schema.org/name> ?pname .
#?obj <http://schema.org/name> ?oname .
#?c <http://schema.org/name> ?cname .
}
#GROUP BY ?wname ?cname
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('num', '42260')]
# 1

# %% [markdown]
# #### Comment
# If we also want the names we can execute this query (I stopped it), and with this query we can also have an example of how the BGP retrieved in task 2 works.

# %%
#If we also want the names we can execute this query (I stopped it)
#Poets and writers with place of birth or place of death or place of burial located in France or Germany 
queryString = """
SELECT ?wname (GROUP_CONCAT(DISTINCT ?pname ; separator = ", ") AS ?info) ?cname
WHERE { 

# ?per wdt:P106 ?job ;
    # ?p ?obj .
# ?obj wdt:P17 ?c .

FILTER(?job = wd:Q36180 || ?job = wd:Q49757).
FILTER(?p = wdt:P19 || ?p = wdt:P20 || ?p = wdt:P119).
FILTER(?c = wd:Q142 || ?c = wd:Q183).

# ?per <http://schema.org/name> ?wname.
# ?p <http://schema.org/name> ?pname .
# ?obj <http://schema.org/name> ?oname .
# ?c <http://schema.org/name> ?cname .
}
GROUP BY ?wname ?cname
ORDER BY ASC (?wname)
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('wname', 'A. Augustin-Thierry'), ('info', 'place of birth, place of death'), ('cname', 'France')]
# [('wname', 'A. F. Koshko'), ('info', 'place of death'), ('cname', 'France')]
# [('wname', 'A. Gennevraye'), ('info', 'place of birth, place of death'), ('cname', 'France')]
# [('wname', 'A. I︠A︡blonovskīĭ'), ('info', 'place of death'), ('cname', 'France')]
# [('wname', 'A. Josef Štěpánek'), ('info', 'place of death'), ('cname', 'Germany')]
# [('wname', 'A. M. W. Stirling'), ('info', 'place of death'), ('cname', 'Germany')]
# [('wname', 'A. O. Osipovich-Novodvorskiĭ'), ('info', 'place of death'), ('cname', 'France')]
# [('wname', 'A. Rennikov'), ('info', 'place of burial, place of death'), ('cname', 'France')]
# [('wname', 'A. S. H. Pelikan'), ('info', 'place of birth'), ('cname', 'Germany')]
# [('wname', 'A. Verley'), ('info', 'place of birth'), ('cname', 'France')]
# [('wname', 'A.-Sébastien Kauffmann'), ('info', 'place of birth, place of death'), ('cname', 'France')]
# [('wname', 'Aar van de Werfhorst'), ('info', 'place of birth'), ('cname', 'Germany')]
# [('wname', 'Aaron Bernstein'), ('info', 'place of death'), ('cname', 'Germany')]
# [('wname', 'Aaron Halle-Wolfssohn'), ('info', 'place of death'), ('cname', 'Germany')]
# [('wname', 'Aaron Tänzer'), ('info', 'place of death'), ('cname', 'Germany')]
# [('wname', 'Abba Mari'), ('info', 'place of birth'), ('cname', 'France')]
# [('wname', 'Abbas'), ('info', 'place of death'), ('cname', 'France')]
# [('wname', 'Abbas Kiarostami'), ('info', 'place of death'), ('cname', 'France')]
# [('wname', 'Abbo Cernuus'), ('info', 'place of birth, place of death'), ('cname', 'France')]
# [('wname', 'Abbo of Fleury'), ('info', 'place of birth, place of death'), ('cname', 'France')]
# [('wname', 'Abbot Oliba'), ('info', 'place of death'), ('cname', 'France')]
# [('wname', 'Abbot Suger'), ('info', 'place of birth, place of burial, place of death'), ('cname', 'France')]
# [('wname', 'Abbé Alta'), ('info', 'place of birth, place of death'), ('cname', 'France')]
# [('wname', 'Abbé Aubert'), ('info', 'place of birth, place of death'), ('cname', 'France')]
# [('wname', 'Abbé de Villiers'), ('info', 'place of birth'), ('cname', 'France')]
# [('wname', 'Abd al Malik'), ('info', 'place of birth'), ('cname', 'France')]
# [('wname', 'Abd-ru-shin'), ('info', 'place of birth, place of death'), ('cname', 'Germany')]
# [('wname', 'Abdel Hafed Benotman'), ('info', 'place of birth, place of burial'), ('cname', 'France')]
# [('wname', 'Abdellah Mohia'), ('info', 'place of death'), ('cname', 'France')]
# [('wname', 'Abdelmalek Sayad'), ('info', 'place of death'), ('cname', 'France')]
# [('wname', 'Abdelwahab Meddeb'), ('info', 'place of death'), ('cname', 'France')]
# [('wname', 'Abdoldjavad Falaturi'), ('info', 'place of death'), ('cname', 'Germany')]
# [('wname', 'Abdou Baco'), ('info', 'place of birth'), ('cname', 'France')]
# [('wname', 'Abdul Razzak Abdul Wahed'), ('info', 'place of death'), ('cname', 'France')]
# [('wname', 'Abdulla Aliş'), ('info', 'place of death'), ('cname', 'Germany')]
# [('wname', 'Abdó Poggi'), ('info', 'place of birth'), ('cname', 'France')]
# [('wname', 'Abel Bonnard'), ('info', 'place of birth'), ('cname', 'France')]
# [('wname', 'Abel Hermant'), ('info', 'place of birth, place of death'), ('cname', 'France')]
# [('wname', 'Abel Hugo'), ('info', 'place of birth, place of burial, place of death'), ('cname', 'France')]
# [('wname', 'Abel Leblanc'), ('info', 'place of birth, place of death'), ('cname', 'France')]
# [('wname', 'Abel Mathieu'), ('info', 'place of birth'), ('cname', 'France')]
# [('wname', 'Abel Quentin'), ('info', 'place of birth'), ('cname', 'France')]
# [('wname', 'Abel-François Villemain'), ('info', 'place of birth, place of burial, place of death'), ('cname', 'France')]
# [('wname', 'Abelino Barriola'), ('info', 'place of death'), ('cname', 'France')]
# [('wname', 'Abeozen'), ('info', 'place of birth, place of death'), ('cname', 'France')]
# [('wname', 'Abraham Bedersi'), ('info', 'place of birth'), ('cname', 'France')]
# [('wname', 'Abraham Bormeester'), ('info', 'place of birth'), ('cname', 'Germany')]
# [('wname', 'Abraham Bosse'), ('info', 'place of birth, place of death'), ('cname', 'France')]
# [('wname', 'Abraham Buchholzer'), ('info', 'place of birth'), ('cname', 'Germany')]
# [('wname', 'Abraham Calovius'), ('info', 'place of death'), ('cname', 'Germany')]
# [('wname', 'Abraham Danon'), ('info', 'place of death'), ('cname', 'France')]
# [('wname', 'Abraham Giulchandanian'), ('info', 'place of death'), ('cname', 'France')]
# [('wname', 'Abraham Halbert'), ('info', 'place of death'), ('cname', 'Germany')]
# [('wname', 'Abraham Kutter'), ('info', 'place of birth'), ('cname', 'Germany')]
# [('wname', 'Abraham Louis Michell'), ('info', 'place of death'), ('cname', 'Germany')]
# [('wname', 'Abraham Remy'), ('info', 'place of birth'), ('cname', 'France')]
# [('wname', 'Abraham Wieling'), ('info', 'place of birth'), ('cname', 'Germany')]
# [('wname', 'Abraham Wolff'), ('info', 'place of birth'), ('cname', 'Germany')]
# [('wname', 'Abraham a Sancta Clara'), ('info', 'place of birth'), ('cname', 'Germany')]
# [('wname', 'Abraham de Vermeil'), ('info', 'place of birth, place of death'), ('cname', 'France')]
# [('wname', 'Abraham de Wicquefort'), ('info', 'place of death'), ('cname', 'Germany')]
# [('wname', 'Abraham van Mildert'), ('info', 'place of birth'), ('cname', 'Germany')]
# [('wname', 'Abraham von Humbert'), ('info', 'place of birth, place of death'), ('cname', 'Germany')]
# [('wname', 'Abram B. Enns'), ('info', 'place of burial, place of death'), ('cname', 'Germany')]
# [('wname', 'Achille Deville'), ('info', 'place of birth, place of burial, place of death'), ('cname', 'France')]
# [('wname', 'Achille Essebac'), ('info', 'place of birth, place of death'), ('cname', 'France')]
# [('wname', 'Achille Eyraud'), ('info', 'place of birth, place of burial'), ('cname', 'France')]
# [('wname', 'Achille Maffre de Baugé'), ('info', 'place of birth, place of death'), ('cname', 'France')]
# [('wname', 'Achille Millien'), ('info', 'place of birth, place of death'), ('cname', 'France')]
# [('wname', 'Achille Montel'), ('info', 'place of birth'), ('cname', 'France')]
# [('wname', 'Achille Mélandri'), ('info', 'place of birth'), ('cname', 'France')]
# [('wname', 'Achille Paysant'), ('info', 'place of birth, place of death'), ('cname', 'France')]
# [('wname', 'Achille Rouquet'), ('info', 'place of birth, place of death'), ('cname', 'France')]
# [('wname', 'Achille Steens'), ('info', 'place of birth, place of death'), ('cname', 'France')]
# [('wname', 'Achille Tournier'), ('info', 'place of birth'), ('cname', 'France')]
# [('wname', 'Achille de Lauzières'), ('info', 'place of death'), ('cname', 'France')]
# [('wname', 'Achille du Clésieux'), ('info', 'place of birth, place of death'), ('cname', 'France')]
# [('wname', 'Achille-Henri Baubeau de Secondigné'), ('info', 'place of birth'), ('cname', 'France')]
# [('wname', 'Achilleas Kyrou'), ('info', 'place of death'), ('cname', 'France')]
# [('wname', 'Achim Amme'), ('info', 'place of birth'), ('cname', 'Germany')]
# [('wname', 'Achim Anderer'), ('info', 'place of birth, place of death'), ('cname', 'Germany')]
# [('wname', 'Achim Anders'), ('info', 'place of birth, place of death'), ('cname', 'Germany')]
# [('wname', 'Achim Baumgarten'), ('info', 'place of birth'), ('cname', 'Germany')]
# [('wname', 'Achim Brankačk'), ('info', 'place of birth, place of death'), ('cname', 'Germany')]
# [('wname', 'Achim Bröger'), ('info', 'place of birth'), ('cname', 'Germany')]
# [('wname', 'Achim Kilian'), ('info', 'place of birth, place of death'), ('cname', 'Germany')]
# [('wname', 'Achim Knüpffer von Hirschheydt'), ('info', 'place of birth, place of death'), ('cname', 'Germany')]
# [('wname', 'Achim Konejung'), ('info', 'place of birth'), ('cname', 'Germany')]
# [('wname', 'Achim Mehnert'), ('info', 'place of birth, place of death'), ('cname', 'Germany')]
# [('wname', 'Achim Metzkes'), ('info', 'place of birth'), ('cname', 'Germany')]
# [('wname', 'Achim Schnurrer'), ('info', 'place of birth'), ('cname', 'Germany')]
# [('wname', 'Achim Stößer'), ('info', 'place of birth'), ('cname', 'Germany')]
# [('wname', 'Achim Szymanski'), ('info', 'place of birth'), ('cname', 'Germany')]
# [('wname', 'Achim Wagner'), ('info', 'place of birth'), ('cname', 'Germany')]
# [('wname', 'Achim Wannicke'), ('info', 'place of birth'), ('cname', 'Germany')]
# [('wname', 'Achim von Borries'), ('info', 'place of birth'), ('cname', 'Germany')]
# [('wname', 'Ada Battke'), ('info', 'place of birth'), ('cname', 'Germany')]
# [('wname', 'Ada Dorian'), ('info', 'place of birth'), ('cname', 'Germany')]
# [('wname', 'Ada Halenza'), ('info', 'place of birth, place of death'), ('cname', 'Germany')]
# [('wname', 'Ada Kretzer-Hartl'), ('info', 'place of birth, place of death'), ('cname', 'Germany')]
# [('wname', 'Ada Pinelli'), ('info', 'place of death'), ('cname', 'Germany')]
# [('wname', 'Ada Roon'), ('info', 'place of birth, place of death'), ('cname', 'Germany')]
# [('wname', 'Ada von Boeselager'), ('info', 'place of birth'), ('cname', 'Germany')]
# [('wname', 'Ada von Voß'), ('info', 'place of death'), ('cname', 'Germany')]
# [('wname', 'Adah Isaacs Menken'), ('info', 'place of burial, place of death'), ('cname', 'France')]
# [('wname', 'Adalard of Corbie'), ('info', 'place of death'), ('cname', 'France')]
# [('wname', 'Adalberon'), ('info', 'place of birth, place of death'), ('cname', 'France')]
# [('wname', 'Adalbert Cohrs'), ('info', 'place of birth'), ('cname', 'Germany')]
# [('wname', 'Adalbert Ebner'), ('info', 'place of birth, place of burial, place of death'), ('cname', 'Germany')]
# [('wname', 'Adalbert Herrmann'), ('info', 'place of birth, place of death'), ('cname', 'Germany')]
# [('wname', 'Adalbert Ibrahim Kapandji'), ('info', 'place of birth, place of burial, place of death'), ('cname', 'France')]
# [('wname', 'Adalbert Johann Polsterer'), ('info', 'place of birth'), ('cname', 'Germany')]
# [('wname', 'Adalbert Luntowski'), ('info', 'place of death'), ('cname', 'Germany')]
# [('wname', 'Adalbert Müller'), ('info', 'place of birth, place of death'), ('cname', 'Germany')]
# [('wname', 'Adalbert Philipp Cammerer'), ('info', 'place of birth'), ('cname', 'Germany')]
# [('wname', 'Adalbert Seipolt'), ('info', 'place of death'), ('cname', 'Germany')]
# [('wname', 'Adalbert Votteler'), ('info', 'place of birth, place of death'), ('cname', 'Germany')]
# [('wname', 'Adalbert of Mainz'), ('info', 'place of burial, place of death'), ('cname', 'Germany')]
# [('wname', 'Adalbert von Frankenberg und Ludwigsdorff'), ('info', 'place of birth, place of death'), ('cname', 'Germany')]
# [('wname', 'Adalbert von Hanstein'), ('info', 'place of birth, place of death'), ('cname', 'Germany')]
# [('wname', 'Adalbert-Henri Foucault de Mondion'), ('info', 'place of birth, place of death'), ('cname', 'France')]
# [('wname', 'Adalgod von Osterburg'), ('info', 'place of burial, place of death'), ('cname', 'Germany')]
# [('wname', 'Adalmar Breden'), ('info', 'place of birth'), ('cname', 'Germany')]
# [('wname', 'Adam Adam'), ('info', 'place of birth'), ('cname', 'Germany')]
# [('wname', 'Adam Albert'), ('info', 'place of birth'), ('cname', 'Germany')]
# [('wname', 'Adam Anton'), ('info', 'place of birth, place of death'), ('cname', 'Germany')]
# [('wname', 'Adam Benedict Spitzner'), ('info', 'place of birth, place of death'), ('cname', 'Germany')]
# [('wname', 'Adam Billaut'), ('info', 'place of birth, place of death'), ('cname', 'France')]
# [('wname', 'Adam Blackwood'), ('info', 'place of death'), ('cname', 'France')]
# [('wname', 'Adam Bohorič'), ('info', 'place of death'), ('cname', 'France')]
# [('wname', 'Adam Brand'), ('info', 'place of birth'), ('cname', 'Germany')]
# [('wname', 'Adam Brendel'), ('info', 'place of birth, place of death'), ('cname', 'Germany')]
# [('wname', 'Adam Charles Gustave Desmazures'), ('info', 'place of birth'), ('cname', 'France')]
# [('wname', 'Adam Elias von Siebold'), ('info', 'place of birth, place of death'), ('cname', 'Germany')]
# [('wname', 'Adam Erdmann Mirus'), ('info', 'place of birth, place of death'), ('cname', 'Germany')]
# [('wname', 'Adam Friedrich Geisler'), ('info', 'place of birth'), ('cname', 'Germany')]
# [('wname', 'Adam Friedrich Koch'), ('info', 'place of birth, place of death'), ('cname', 'Germany')]
# [('wname', 'Adam Gottfried Uhlich'), ('info', 'place of birth, place of death'), ('cname', 'Germany')]
# [('wname', 'Adam Gottlob Schirach'), ('info', 'place of birth, place of death'), ('cname', 'Germany')]
# [('wname', 'Adam Gschwend'), ('info', 'place of birth'), ('cname', 'Germany')]
# [('wname', 'Adam Herold'), ('info', 'place of birth, place of death'), ('cname', 'Germany')]
# [('wname', 'Adam Jerzy Czartoryski'), ('info', 'place of burial, place of death'), ('cname', 'France')]
# [('wname', 'Adam Josef Cüppers'), ('info', 'place of birth, place of death'), ('cname', 'Germany')]
# [('wname', 'Adam Karrillon'), ('info', 'place of birth, place of death'), ('cname', 'Germany')]
# [('wname', 'Adam Müller'), ('info', 'place of birth, place of death'), ('cname', 'Germany')]
# [('wname', 'Adam Olearius'), ('info', 'place of birth, place of death'), ('cname', 'Germany')]
# [('wname', 'Adam Pastor'), ('info', 'place of birth'), ('cname', 'Germany')]
# [('wname', 'Adam Poelmann'), ('info', 'place of birth'), ('cname', 'Germany')]
# [('wname', 'Adam Reusner'), ('info', 'place of birth, place of death'), ('cname', 'Germany')]
# [('wname', 'Adam Riccius'), ('info', 'place of birth'), ('cname', 'Germany')]
# [('wname', 'Adam Saint-Moore'), ('info', 'place of birth'), ('cname', 'France')]
# [('wname', 'Adam Scharrer'), ('info', 'place of birth, place of burial, place of death'), ('cname', 'Germany')]
# [('wname', 'Adam Seide'), ('info', 'place of birth, place of death'), ('cname', 'Germany')]
# [('wname', 'Adam Simonson'), ('info', 'place of birth'), ('cname', 'Germany')]
# [('wname', 'Adam Storck'), ('info', 'place of birth, place of death'), ('cname', 'Germany')]
# [('wname', 'Adam Thorpe'), ('info', 'place of birth'), ('cname', 'France')]
# [('wname', 'Adam Trabert'), ('info', 'place of birth'), ('cname', 'Germany')]
# [('wname', 'Adam Tribbechow'), ('info', 'place of birth, place of death'), ('cname', 'Germany')]
# [('wname', 'Adam Tülsner'), ('info', 'place of birth, place of death'), ('cname', 'Germany')]
# [('wname', 'Adam Walasser'), ('info', 'place of birth, place of death'), ('cname', 'Germany')]
# [('wname', 'Adam Weishaupt'), ('info', 'place of birth, place of death'), ('cname', 'Germany')]
# [('wname', 'Adam Wrede'), ('info', 'place of birth, place of death'), ('cname', 'Germany')]
# [('wname', 'Adam Zacharias Schirach'), ('info', 'place of death'), ('cname', 'Germany')]
# [('wname', 'Adam de la Halle'), ('info', 'place of birth'), ('cname', 'France')]
# [('wname', 'Adam of Bremen'), ('info', 'place of birth'), ('cname', 'Germany')]
# [('wname', 'Adam of Fulda'), ('info', 'place of birth, place of death'), ('cname', 'Germany')]
# [('wname', 'Adam of Perseigne'), ('info', 'place of birth, place of death'), ('cname', 'France')]
# [('wname', 'Adam von Bodenstein'), ('info', 'place of birth'), ('cname', 'Germany')]
# [('wname', 'Adamantios Korais'), ('info', 'place of burial, place of death'), ('cname', 'France')]
# [('wname', 'Adda von Königsegg'), ('info', 'place of death'), ('cname', 'Germany')]
# [('wname', 'Adda von Liliencron'), ('info', 'place of birth'), ('cname', 'Germany')]
# [('wname', 'Adelaide Filleul, Marquise de Souza-Botelho'), ('info', 'place of birth, place of burial, place of death'), ('cname', 'France')]
# [('wname', 'Adelbert Heinrich von Baudissin'), ('info', 'place of death'), ('cname', 'Germany')]
# [('wname', 'Adelbert Natorp'), ('info', 'place of birth, place of death'), ('cname', 'Germany')]
# [('wname', 'Adelbert Weinstein'), ('info', 'place of birth, place of death'), ('cname', 'Germany')]
# [('wname', 'Adelbert von Bornstedt'), ('info', 'place of birth, place of death'), ('cname', 'Germany')]
# [('wname', 'Adelbert von Chamisso'), ('info', 'place of burial, place of death'), ('cname', 'Germany')]
# [('wname', 'Adelbert von Chamisso'), ('info', 'place of birth'), ('cname', 'France')]
# [('wname', 'Adelbert von Keller'), ('info', 'place of birth, place of death'), ('cname', 'Germany')]
# [('wname', 'Adele Elkan'), ('info', 'place of birth'), ('cname', 'Germany')]
# [('wname', 'Adele Gerhard'), ('info', 'place of birth, place of death'), ('cname', 'Germany')]
# [('wname', 'Adele Osterloh'), ('info', 'place of birth, place of death'), ('cname', 'Germany')]
# [('wname', 'Adele Schopenhauer'), ('info', 'place of birth, place of burial, place of death'), ('cname', 'Germany')]
# [('wname', 'Adelheid Bernhardt'), ('info', 'place of birth, place of death'), ('cname', 'Germany')]
# [('wname', 'Adelheid Langmann'), ('info', 'place of birth, place of death'), ('cname', 'Germany')]
# [('wname', 'Adelheid Petersen'), ('info', 'place of birth, place of death'), ('cname', 'Germany')]
# [('wname', 'Adelheid Reinbold'), ('info', 'place of birth'), ('cname', 'Germany')]
# [('wname', 'Adelheid Rosalie Lackemann'), ('info', 'place of birth, place of death'), ('cname', 'Germany')]
# [('wname', 'Adelheid Stier'), ('info', 'place of birth'), ('cname', 'Germany')]
# [('wname', 'Adelheid Wette'), ('info', 'place of birth, place of death'), ('cname', 'Germany')]
# [('wname', 'Adelheid Wildermuth'), ('info', 'place of birth, place of death'), ('cname', 'Germany')]
# [('wname', 'Adelheid von Carolath-Beuthen'), ('info', 'place of birth, place of death'), ('cname', 'Germany')]
# [('wname', 'Adelheid von Schorn'), ('info', 'place of birth'), ('cname', 'Germany')]
# [('wname', 'Adelheid von Stolterfoth'), ('info', 'place of birth'), ('cname', 'Germany')]
# [('wname', 'Adelin Moulis'), ('info', 'place of birth, place of death'), ('cname', 'France')]
# [('wname', 'Adelina Yzac'), ('info', 'place of birth'), ('cname', 'France')]
# [('wname', 'Adeline Baldacchino'), ('info', 'place of birth'), ('cname', 'France')]
# [('wname', 'Adeline Blondieau'), ('info', 'place of birth'), ('cname', 'France')]
# [('wname', 'Adeline Neetesonne'), ('info', 'place of birth'), ('cname', 'France')]
# [('wname', 'Adeline Volckhausen'), ('info', 'place of birth, place of death'), ('cname', 'Germany')]
# [('wname', 'Adeline zu Rantzau'), ('info', 'place of birth, place of death'), ('cname', 'Germany')]
# [('wname', 'Ademar Jordan'), ('info', 'place of birth'), ('cname', 'France')]
# [('wname', 'Ademar de Rocaficha'), ('info', 'place of birth'), ('cname', 'France')]
# [('wname', 'Ademar lo Negre'), ('info', 'place of birth'), ('cname', 'France')]
# [('wname', 'Adhémard Leclère'), ('info', 'place of birth, place of death'), ('cname', 'France')]
# [('wname', 'Adi Hübel'), ('info', 'place of birth'), ('cname', 'Germany')]
# [('wname', 'Adine Gemberg'), ('info', 'place of death'), ('cname', 'Germany')]
# [('wname', 'Adine Joliveau'), ('info', 'place of birth, place of death'), ('cname', 'France')]
# [('wname', 'Adine Riom'), ('info', 'place of birth, place of death'), ('cname', 'France')]
# [('wname', 'Ado'), ('info', 'place of birth, place of death'), ('cname', 'France')]
# [('wname', 'Ado Grenzstein'), ('info', 'place of death'), ('cname', 'France')]
# [('wname', 'Adolar Gerhard'), ('info', 'place of birth, place of death'), ('cname', 'Germany')]
# [('wname', 'Adolf Antze'), ('info', 'place of birth'), ('cname', 'Germany')]
# [('wname', 'Adolf Arenson'), ('info', 'place of birth'), ('cname', 'Germany')]
# [('wname', 'Adolf Bacmeister'), ('info', 'place of birth, place of death'), ('cname', 'Germany')]
# [('wname', 'Adolf Bahn'), ('info', 'place of birth, place of death'), ('cname', 'Germany')]
# [('wname', 'Adolf Bartels'), ('info', 'place of birth, place of death'), ('cname', 'Germany')]
# [('wname', 'Adolf Bastian'), ('info', 'place of birth, place of burial'), ('cname', 'Germany')]
# [('wname', 'Adolf Beiss'), ('info', 'place of birth, place of death'), ('cname', 'Germany')]
# [('wname', 'Adolf Bernhard Christoph Hilgenfeld'), ('info', 'place of birth, place of burial, place of death'), ('cname', 'Germany')]
# [('wname', 'Adolf Bernhard Marx'), ('info', 'place of birth, place of burial, place of death'), ('cname', 'Germany')]
# [('wname', 'Adolf Bessell'), ('info', 'place of birth'), ('cname', 'Germany')]
# [('wname', 'Adolf Bock von Wülfingen'), ('info', 'place of birth'), ('cname', 'Germany')]
# [('wname', 'Adolf Borbstaedt'), ('info', 'place of death'), ('cname', 'Germany')]
# [('wname', 'Adolf Brand'), ('info', 'place of birth, place of burial, place of death'), ('cname', 'Germany')]
# [('wname', 'Adolf Bube'), ('info', 'place of birth, place of death'), ('cname', 'Germany')]
# [('wname', 'Adolf Buff'), ('info', 'place of birth'), ('cname', 'Germany')]
# [('wname', 'Adolf Böttger'), ('info', 'place of birth, place of death'), ('cname', 'Germany')]
# [('wname', 'Adolf Büchle'), ('info', 'place of birth'), ('cname', 'Germany')]
# [('wname', 'Adolf Dessauer'), ('info', 'place of birth'), ('cname', 'Germany')]
# [('wname', 'Adolf Doerr'), ('info', 'place of death'), ('cname', 'Germany')]
# [('wname', 'Adolf Dresen'), ('info', 'place of birth, place of burial, place of death'), ('cname', 'Germany')]
# [('wname', 'Adolf Dresler'), ('info', 'place of birth, place of death'), ('cname', 'Germany')]
# [('wname', 'Adolf Droop'), ('info', 'place of birth, place of death'), ('cname', 'Germany')]
# [('wname', 'Adolf Dyroff'), ('info', 'place of birth, place of death'), ('cname', 'Germany')]
# [('wname', 'Adolf Ebert'), ('info', 'place of birth, place of death'), ('cname', 'Germany')]
# [('wname', 'Adolf Eckstein'), ('info', 'place of death'), ('cname', 'Germany')]
# [('wname', 'Adolf Edward Jacobi'), ('info', 'place of birth, place of death'), ('cname', 'Germany')]
# [('wname', 'Adolf Eichenseer'), ('info', 'place of birth, place of death'), ('cname', 'Germany')]
# [('wname', 'Adolf Endler'), ('info', 'place of birth, place of death'), ('cname', 'Germany')]
# [('wname', 'Adolf Ey'), ('info', 'place of birth, place of death'), ('cname', 'Germany')]
# [('wname', 'Adolf Fauth'), ('info', 'place of birth, place of death'), ('cname', 'Germany')]
# [('wname', 'Adolf Flachs'), ('info', 'place of death'), ('cname', 'Germany')]
# [('wname', 'Adolf Friedrich Furchau'), ('info', 'place of birth, place of death'), ('cname', 'Germany')]
# [('wname', 'Adolf Friedrich Seubert'), ('info', 'place of birth, place of death'), ('cname', 'Germany')]
# [('wname', 'Adolf Friedrich von Reinhard'), ('info', 'place of birth, place of death'), ('cname', 'Germany')]
# [('wname', 'Adolf Friedrich von Witzendorff'), ('info', 'place of birth, place of death'), ('cname', 'Germany')]
# [('wname', 'Adolf Friedrich von Schack'), ('info', 'place of birth, place of burial'), ('cname', 'Germany')]
# [('wname', 'Adolf Frisé'), ('info', 'place of birth, place of death'), ('cname', 'Germany')]
# [('wname', 'Adolf Galliker'), ('info', 'place of birth'), ('cname', 'France')]
# [('wname', 'Adolf Giesen'), ('info', 'place of birth, place of death'), ('cname', 'Germany')]
# [('wname', 'Adolf Glaser'), ('info', 'place of birth, place of death'), ('cname', 'Germany')]
# [('wname', 'Adolf Glassbrenner'), ('info', 'place of birth, place of death'), ('cname', 'Germany')]
# [('wname', 'Adolf Gottlob'), ('info', 'place of birth'), ('cname', 'Germany')]
# [('wname', 'Adolf Groth'), ('info', 'place of birth, place of burial'), ('cname', 'Germany')]
# [('wname', 'Adolf Görtz'), ('info', 'place of birth'), ('cname', 'Germany')]
# [('wname', 'Adolf Göschel'), ('info', 'place of birth, place of death'), ('cname', 'Germany')]
# [('wname', 'Adolf Hahn'), ('info', 'place of birth, place of death'), ('cname', 'Germany')]
# [('wname', 'Adolf Hauert'), ('info', 'place of birth'), ('cname', 'Germany')]
# [('wname', 'Adolf Hechelmann'), ('info', 'place of birth, place of death'), ('cname', 'Germany')]
# [('wname', 'Adolf Heilborn'), ('info', 'place of birth, place of death'), ('cname', 'Germany')]
# [('wname', 'Adolf Heinrich Ebeling'), ('info', 'place of birth, place of death'), ('cname', 'Germany')]
# [('wname', 'Adolf Heinzlmeier'), ('info', 'place of birth'), ('cname', 'Germany')]
# [('wname', 'Adolf Heitmann'), ('info', 'place of birth, place of death'), ('cname', 'Germany')]
# [('wname', 'Adolf Hildebrand'), ('info', 'place of birth, place of death'), ('cname', 'Germany')]
# [('wname', 'Adolf Himmel'), ('info', 'place of birth'), ('cname', 'Germany')]
# [('wname', 'Adolf Holm'), ('info', 'place of birth'), ('cname', 'Germany')]
# [('wname', 'Adolf Holst'), ('info', 'place of birth, place of death'), ('cname', 'Germany')]
# [('wname', 'Adolf Häckermann'), ('info', 'place of birth, place of death'), ('cname', 'Germany')]
# [('wname', 'Adolf Josef Gerstmann'), ('info', 'place of death'), ('cname', 'Germany')]
# [('wname', 'Adolf Kabatek'), ('info', 'place of death'), ('cname', 'Germany')]
# [('wname', 'Adolf Karl Ludwig Lindemann'), ('info', 'place of birth, place of death'), ('cname', 'Germany')]
# [('wname', 'Adolf Keysser'), ('info', 'place of birth'), ('cname', 'Germany')]
# [('wname', 'Adolf Kiepert'), ('info', 'place of death'), ('cname', 'Germany')]
# [('wname', 'Adolf Knoblauch'), ('info', 'place of death'), ('cname', 'Germany')]
# [('wname', 'Adolf Koelsch'), ('info', 'place of birth'), ('cname', 'Germany')]
# [('wname', 'Adolf Kreis'), ('info', 'place of death'), ('cname', 'Germany')]
# [('wname', 'Adolf Kutschker'), ('info', 'place of death'), ('cname', 'Germany')]
# [('wname', 'Adolf Lapp'), ('info', 'place of birth'), ('cname', 'Germany')]
# [('wname', 'Adolf Lepp'), ('info', 'place of birth, place of death'), ('cname', 'Germany')]
# [('wname', 'Adolf Linhardt'), ('info', 'place of birth'), ('cname', 'Germany')]
# [('wname', 'Adolf Löhr'), ('info', 'place of birth'), ('cname', 'Germany')]
# [('wname', 'Adolf Matthias Hildebrandt'), ('info', 'place of birth, place of death'), ('cname', 'Germany')]
# [('wname', 'Adolf May'), ('info', 'place of birth'), ('cname', 'Germany')]
# [('wname', 'Adolf Mensching'), ('info', 'place of birth, place of death'), ('cname', 'Germany')]
# [('wname', 'Adolf Mitzenius'), ('info', 'place of birth, place of death'), ('cname', 'Germany')]
# [('wname', 'Adolf Mühry'), ('info', 'place of birth, place of death'), ('cname', 'Germany')]
# [('wname', 'Adolf Müller'), ('info', 'place of birth, place of death'), ('cname', 'Germany')]
# [('wname', 'Adolf Müller-Palm'), ('info', 'place of birth, place of burial'), ('cname', 'Germany')]
# [('wname', 'Adolf Müllner'), ('info', 'place of birth, place of death'), ('cname', 'Germany')]
# [('wname', 'Adolf Mützelburg'), ('info', 'place of birth, place of death'), ('cname', 'Germany')]
# [('wname', 'Adolf Neeff'), ('info', 'place of birth, place of death'), ('cname', 'Germany')]
# [('wname', 'Adolf Nekum'), ('info', 'place of burial'), ('cname', 'Germany')]
# [('wname', 'Adolf Paul'), ('info', 'place of death'), ('cname', 'Germany')]
# [('wname', 'Adolf Peter Krönke'), ('info', 'place of birth, place of death'), ('cname', 'Germany')]
# [('wname', 'Adolf Peters'), ('info', 'place of birth, place of death'), ('cname', 'Germany')]
# [('wname', 'Adolf Pompe'), ('info', 'place of death'), ('cname', 'Germany')]
# [('wname', 'Adolf Potthoff'), ('info', 'place of birth'), ('cname', 'Germany')]
# [('wname', 'Adolf Saager'), ('info', 'place of birth'), ('cname', 'Germany')]
# [('wname', 'Adolf Scheer'), ('info', 'place of birth, place of death'), ('cname', 'Germany')]
# [('wname', 'Adolf Schirmer'), ('info', 'place of birth'), ('cname', 'Germany')]
# [('wname', 'Adolf Schmidt-Volker'), ('info', 'place of birth'), ('cname', 'Germany')]
# [('wname', 'Adolf Schmitthenner'), ('info', 'place of birth, place of burial, place of death'), ('cname', 'Germany')]
# [('wname', 'Adolf Schröder'), ('info', 'place of birth, place of death'), ('cname', 'Germany')]
# [('wname', 'Adolf Schults'), ('info', 'place of birth, place of death'), ('cname', 'Germany')]
# [('wname', 'Adolf Sievers'), ('info', 'place of birth, place of death'), ('cname', 'Germany')]
# [('wname', 'Adolf Stahr'), ('info', 'place of birth, place of death'), ('cname', 'Germany')]
# [('wname', 'Adolf Stern'), ('info', 'place of birth, place of death'), ('cname', 'Germany')]
# [('wname', 'Adolf Stoecker'), ('info', 'place of birth'), ('cname', 'Germany')]
# [('wname', 'Adolf Stoltze'), ('info', 'place of birth, place of death'), ('cname', 'Germany')]
# [('wname', 'Adolf Streckfuß'), ('info', 'place of birth, place of burial, place of death'), ('cname', 'Germany')]
# [('wname', 'Adolf Strodtmann'), ('info', 'place of birth, place of death'), ('cname', 'Germany')]
# [('wname', 'Adolf Thimme'), ('info', 'place of birth'), ('cname', 'Germany')]
# [('wname', 'Adolf Trieb'), ('info', 'place of birth, place of death'), ('cname', 'Germany')]
# [('wname', 'Adolf Ulrich'), ('info', 'place of birth, place of death'), ('cname', 'Germany')]
# [('wname', 'Adolf Uzarski'), ('info', 'place of birth, place of death'), ('cname', 'Germany')]
# [('wname', 'Adolf Waas'), ('info', 'place of birth, place of death'), ('cname', 'Germany')]
# [('wname', 'Adolf Wagner'), ('info', 'place of birth, place of death'), ('cname', 'Germany')]
# [('wname', 'Adolf Wahrmund'), ('info', 'place of birth'), ('cname', 'Germany')]
# [('wname', 'Adolf Wechßler'), ('info', 'place of birth, place of death'), ('cname', 'Germany')]
# [('wname', 'Adolf Welte'), ('info', 'place of birth'), ('cname', 'Germany')]
# [('wname', 'Adolf Wilbrandt'), ('info', 'place of birth, place of burial, place of death'), ('cname', 'Germany')]
# [('wname', 'Adolf Woderich'), ('info', 'place of birth, place of death'), ('cname', 'Germany')]
# [('wname', 'Adolf Wolfhard'), ('info', 'place of birth'), ('cname', 'Germany')]
# [('wname', 'Adolf Wurmbach'), ('info', 'place of birth, place of death'), ('cname', 'Germany')]
# [('wname', 'Adolf Wuttke'), ('info', 'place of death'), ('cname', 'Germany')]
# [('wname', 'Adolf Wüstefeld'), ('info', 'place of birth, place of death'), ('cname', 'Germany')]
# [('wname', 'Adolf Zahn'), ('info', 'place of death'), ('cname', 'Germany')]
# [('wname', 'Adolf Zehlicke'), ('info', 'place of birth, place of death'), ('cname', 'Germany')]
# [('wname', 'Adolf Zeising'), ('info', 'place of birth, place of burial, place of death'), ('cname', 'Germany')]
# [('wname', 'Adolf Zeller'), ('info', 'place of birth, place of death'), ('cname', 'Germany')]
# [('wname', 'Adolf von Basedow'), ('info', 'place of birth, place of death'), ('cname', 'Germany')]
# [('wname', 'Adolf von Berlichingen'), ('info', 'place of birth, place of death'), ('cname', 'Germany')]
# [('wname', 'Adolf von Doß'), ('info', 'place of birth'), ('cname', 'Germany')]
# [('wname', 'Adolf von Essen'), ('info', 'place of death'), ('cname', 'Germany')]
# [('wname', 'Adolf von Hatzfeld'), ('info', 'place of birth, place of death'), ('cname', 'Germany')]
# [('wname', 'Adolf von Schübler'), ('info', 'place of birth, place of death'), ('cname', 'Germany')]
# [('wname', 'Adolf von Wilke'), ('info', 'place of birth, place of death'), ('cname', 'Germany')]
# [('wname', 'Adolph Albert Friedrich Wilhelm von Danckelmann'), ('info', 'place of death'), ('cname', 'Germany')]
# [('wname', 'Adolph Bogislav Grulich'), ('info', 'place of birth, place of death'), ('cname', 'Germany')]
# [('wname', 'Adolph Freiherr Knigge'), ('info', 'place of birth, place of burial, place of death'), ('cname', 'Germany')]
# [('wname', 'Adolph Gottfried Volusius'), ('info', 'place of birth, place of death'), ('cname', 'Germany')]
# [('wname', 'Adolph Grimminger'), ('info', 'place of birth, place of death'), ('cname', 'Germany')]
# [('wname', 'Adolph Hausrath'), ('info', 'place of birth, place of burial, place of death'), ('cname', 'Germany')]
# [('wname', 'Adolph Hoffmann'), ('info', 'place of birth, place of burial, place of death'), ('cname', 'Germany')]
# [('wname', 'Adolph Kohut'), ('info', 'place of death'), ('cname', 'Germany')]
# [('wname', 'Adolph Kurt Böhm'), ('info', 'place of birth, place of death'), ('cname', 'Germany')]
# [('wname', "Adolph L'Arronge"), ('info', 'place of birth'), ('cname', 'Germany')]
# [('wname', 'Adolph Wittmaack'), ('info', 'place of birth, place of death'), ('cname', 'Germany')]
# [('wname', 'Adolphe Aderer'), ('info', 'place of birth, place of death'), ('cname', 'France')]
# [('wname', 'Adolphe Allonneau'), ('info', 'place of birth'), ('cname', 'France')]
# [('wname', 'Adolphe Badin'), ('info', 'place of birth'), ('cname', 'France')]
# [('wname', 'Adolphe Basler'), ('info', 'place of death'), ('cname', 'France')]
# [('wname', 'Adolphe Belot'), ('info', 'place of birth, place of death'), ('cname', 'France')]
# [('wname', 'Adolphe Boschot'), ('info', 'place of birth, place of death'), ('cname', 'France')]
# [('wname', 'Adolphe Bossange'), ('info', 'place of birth, place of death'), ('cname', 'France')]
# [('wname', 'Adolphe Desbarrolles'), ('info', 'place of birth, place of burial, place of death'), ('cname', 'France')]
# [('wname', 'Adolphe Dumas'), ('info', 'place of birth, place of death'), ('cname', 'France')]
# [('wname', 'Adolphe Favre'), ('info', 'place of birth, place of burial, place of death'), ('cname', 'France')]
# [('wname', 'Adolphe Gustave Gerhardt'), ('info', 'place of birth'), ('cname', 'France')]
# [('wname', 'Adolphe Javal'), ('info', 'place of birth'), ('cname', 'France')]
# [('wname', 'Adolphe Joanne'), ('info', 'place of birth, place of burial, place of death'), ('cname', 'France')]
# [('wname', 'Adolphe Joseph Carcassonne'), ('info', 'place of birth, place of death'), ('cname', 'France')]
# [('wname', 'Adolphe Lacuzon'), ('info', 'place of birth, place of burial, place of death'), ('cname', 'France')]
# [('wname', 'Adolphe Lèbre'), ('info', 'place of death'), ('cname', 'France')]
# [('wname', 'Adolphe Matthis'), ('info', 'place of birth, place of death'), ('cname', 'France')]
# [('wname', 'Adolphe Michel'), ('info', 'place of birth, place of death'), ('cname', 'France')]
# [('wname', 'Adolphe Pelleport'), ('info', 'place of birth, place of death'), ('cname', 'France')]
# [('wname', 'Adolphe Retté'), ('info', 'place of birth, place of death'), ('cname', 'France')]
# [('wname', 'Adolphe Stoeber'), ('info', 'place of birth, place of death'), ('cname', 'France')]
# [('wname', 'Adolphe Tanquerey'), ('info', 'place of birth, place of death'), ('cname', 'France')]
# [('wname', 'Adolphe Tavernier'), ('info', 'place of birth, place of death'), ('cname', 'France')]
# [('wname', 'Adolphe Thiers'), ('info', 'place of birth, place of burial, place of death'), ('cname', 'France')]
# [('wname', 'Adolphe Vard'), ('info', 'place of birth, place of death'), ('cname', 'France')]
# [('wname', 'Adolphe Willette'), ('info', 'place of birth, place of burial, place of death'), ('cname', 'France')]
# [('wname', "Adolphe d'Avril"), ('info', 'place of birth, place of death'), ('cname', 'France')]
# [('wname', "Adolphe d'Ennery"), ('info', 'place of birth, place of burial, place of death'), ('cname', 'France')]
# [('wname', "Adolphe d'Houdetot"), ('info', 'place of birth, place of death'), ('cname', 'France')]
# [('wname', 'Adolphe de Coston'), ('info', 'place of birth, place of death'), ('cname', 'France')]
# [('wname', 'Adolphe de Fontaine de Resbecq'), ('info', 'place of birth, place of death'), ('cname', 'France')]
# [('wname', 'Adolphe de Leuven'), ('info', 'place of birth, place of death'), ('cname', 'France')]
# [('wname', 'Adolphe de Saint-Valry'), ('info', 'place of birth, place of death'), ('cname', 'France')]
# [('wname', 'Adolphe-Simonis Empis'), ('info', 'place of birth, place of burial, place of death'), ('cname', 'France')]
# [('wname', 'Adolphine von Werdeck'), ('info', 'place of birth, place of death'), ('cname', 'Germany')]
# [('wname', 'Adon Lacroix'), ('info', 'place of birth'), ('cname', 'France')]
# [('wname', 'Adonis Kyrou'), ('info', 'place of death'), ('cname', 'France')]
# [('wname', 'Adrian Matejka'), ('info', 'place of birth'), ('cname', 'Germany')]
# [('wname', 'Adriana Salem'), ('info', 'place of burial'), ('cname', 'France')]
# [('wname', 'Adriano Sack'), ('info', 'place of birth'), ('cname', 'Germany')]
# [('wname', 'Adrianus Turnebus'), ('info', 'place of birth, place of death'), ('cname', 'France')]
# [('wname', 'Adrien Bertrand'), ('info', 'place of birth, place of death'), ('cname', 'France')]
# [('wname', 'Adrien Bosc'), ('info', 'place of birth'), ('cname', 'France')]
# [('wname', 'Adrien Dax'), ('info', 'place of birth, place of death'), ('cname', 'France')]
# [('wname', 'Adrien Decourcelle'), ('info', 'place of birth, place of burial, place of death'), ('cname', 'France')]
# [('wname', 'Adrien Finck'), ('info', 'place of birth, place of death'), ('cname', 'France')]
# [('wname', "Adrien François d'Huez"), ('info', 'place of birth, place of death'), ('cname', 'France')]
# [('wname', 'Adrien Goetz'), ('info', 'place of birth'), ('cname', 'France')]
# [('wname', 'Adrien Greslon'), ('info', 'place of birth'), ('cname', 'France')]
# [('wname', 'Adrien Le Bihan'), ('info', 'place of birth'), ('cname', 'France')]
# [('wname', 'Adrien Leroy'), ('info', 'place of birth'), ('cname', 'France')]
# [('wname', 'Adrien Mithouard'), ('info', 'place of birth'), ('cname', 'France')]
# [('wname', 'Adrien Péladan'), ('info', 'place of death'), ('cname', 'France')]
# [('wname', 'Adrien Remacle'), ('info', 'place of birth'), ('cname', 'France')]
# [('wname', 'Adrien Thierry'), ('info', 'place of birth, place of death'), ('cname', 'France')]
# [('wname', 'Adrien Tomas'), ('info', 'place of birth'), ('cname', 'France')]
# [('wname', 'Adrien Viguier'), ('info', 'place of birth, place of death'), ('cname', 'France')]
# [('wname', 'Adrien Vély'), ('info', 'place of birth, place of death'), ('cname', 'France')]
# [('wname', "Adrien d'Amboise"), ('info', 'place of birth, place of death'), ('cname', 'France')]
# [('wname', 'Adrien de Carné'), ('info', 'place of birth, place of death'), ('cname', 'France')]
# [('wname', 'Adrien de Meeûs'), ('info', 'place of death'), ('cname', 'France')]
# [('wname', 'Adrien de Sarrazin'), ('info', 'place of birth, place of death'), ('cname', 'France')]
# [('wname', 'Adrien de Valois'), ('info', 'place of birth'), ('cname', 'France')]
# [('wname', 'Adrien du Hecquet'), ('info', 'place of birth, place of death'), ('cname', 'France')]
# [('wname', 'Adrien-Charles-Alexandre Basset'), ('info', 'place of birth, place of death'), ('cname', 'France')]
# [('wname', 'Adrien-Michel-Hyacinthe Blin de Sainmore'), ('info', 'place of birth, place of death'), ('cname', 'France')]
# [('wname', 'Adrien-Nicolas Piédefer, marquis de La Salle'), ('info', 'place of birth, place of death'), ('cname', 'France')]
# [('wname', 'Adrienne Braun'), ('info', 'place of birth'), ('cname', 'Germany')]
# [('wname', 'Adrienne Cazeilles'), ('info', 'place of birth'), ('cname', 'France')]
# [('wname', 'Adrienne Durand-Tullou'), ('info', 'place of birth, place of death'), ('cname', 'France')]
# [('wname', 'Adrienne Friedlaender'), ('info', 'place of birth'), ('cname', 'Germany')]
# [('wname', 'Adrienne Monnier'), ('info', 'place of birth, place of death'), ('cname', 'France')]
# [('wname', 'Adrienne Sahuqué'), ('info', 'place of birth, place of death'), ('cname', 'France')]
# [('wname', 'Adrienne Thomas'), ('info', 'place of birth'), ('cname', 'France')]
# [('wname', 'Adrine Tatryan'), ('info', 'place of death'), ('cname', 'France')]
# [('wname', 'Adso of Montier-en-Der'), ('info', 'place of birth'), ('cname', 'France')]
# [('wname', 'Ady Henry Kiss'), ('info', 'place of birth'), ('cname', 'Germany')]
# [('wname', 'Adán Jodorowsky'), ('info', 'place of birth'), ('cname', 'France')]
# [('wname', 'Adèle Daminois'), ('info', 'place of birth, place of death'), ('cname', 'France')]
# [('wname', 'Adèle Denys'), ('info', 'place of birth, place of burial, place of death'), ('cname', 'France')]
# [('wname', 'Adèle Esquiros'), ('info', 'place of birth, place of death'), ('cname', 'France')]
# [('wname', 'Adèle Hommaire de Hell'), ('info', 'place of birth'), ('cname', 'France')]
# [('wname', 'Adèle Jarry de Mancy'), ('info', 'place of birth'), ('cname', 'France')]
# [('wname', "Adèle O'Longh"), ('info', 'place of birth'), ('cname', 'France')]
# [('wname', 'Adèle Tariel'), ('info', 'place of birth'), ('cname', 'France')]
# [('wname', 'Adèle Toussaint-Samson'), ('info', 'place of birth'), ('cname', 'France')]
# [('wname', "Adèle d'Osmond"), ('info', 'place of birth, place of death'), ('cname', 'France')]
# [('wname', 'Adèle de Reiset'), ('info', 'place of birth'), ('cname', 'France')]
# [('wname', 'Adélaide-Isabelle-Jeanne Vivien Deschampsy'), ('info', 'place of birth'), ('cname', 'France')]
# [('wname', 'Adélaïde Dufrénoy'), ('info', 'place of birth, place of burial, place of death'), ('cname', 'France')]
# [('wname', 'Adélaïde Gory-Decour'), ('info', 'place of birth, place of death'), ('cname', 'France')]
# [('wname', 'Adélaïde Hadot'), ('info', 'place of birth'), ('cname', 'France')]
# [('wname', 'Adélaïde de Clermont-Tonnerre'), ('info', 'place of birth'), ('cname', 'France')]
# [('wname', "Adélaïde-Louise d'Eckmühl de Blocqueville"), ('info', 'place of birth, place of burial, place of death'), ('cname', 'France')]
# [('wname', 'Aegidius Albertinus'), ('info', 'place of death'), ('cname', 'Germany')]
# [('wname', 'Aemil Ludwig Philipp Schröder'), ('info', 'place of death'), ('cname', 'Germany')]
# [('wname', 'Aemilius Magnus Arborius'), ('info', 'place of birth'), ('cname', 'France')]
# [('wname', 'Aeneas of Paris'), ('info', 'place of death'), ('cname', 'France')]
# [('wname', 'Aenne Franz'), ('info', 'place of birth'), ('cname', 'Germany')]
# [('wname', 'Agathe Israel'), ('info', 'place of birth'), ('cname', 'Germany')]
# [('wname', 'Agathe Lindner-Welk'), ('info', 'place of birth, place of burial, place of death'), ('cname', 'Germany')]
# [('wname', 'Agathe Nalli-Rutenberg'), ('info', 'place of birth, place of death'), ('cname', 'Germany')]
# [('wname', 'Agathe-Pauline Caylac de Caylan'), ('info', 'place of birth, place of death'), ('cname', 'France')]
# [('wname', 'Agathe-Sophie Sasserno'), ('info', 'place of birth, place of burial, place of death'), ('cname', 'France')]
# [('wname', 'Agis Sideras'), ('info', 'place of birth'), ('cname', 'Germany')]
# [('wname', 'Agius'), ('info', 'place of death'), ('cname', 'Germany')]
# [('wname', 'Aglaé Adanson'), ('info', 'place of birth, place of burial'), ('cname', 'France')]
# [('wname', 'Aglaé de Corday'), ('info', 'place of birth'), ('cname', 'France')]
# [('wname', 'Agnellus Schneider'), ('info', 'place of birth, place of death'), ('cname', 'Germany')]
# [('wname', 'Agnes Clancier'), ('info', 'place of birth'), ('cname', 'France')]
# [('wname', 'Agnes Franz'), ('info', 'place of birth'), ('cname', 'Germany')]
# [('wname', 'Agnes Gerstenberg'), ('info', 'place of birth'), ('cname', 'Germany')]
# [('wname', 'Agnes Günther'), ('info', 'place of birth, place of death'), ('cname', 'Germany')]
# [('wname', 'Agnes Hammer'), ('info', 'place of birth'), ('cname', 'Germany')]
# [('wname', 'Agnes Harder'), ('info', 'place of death'), ('cname', 'Germany')]
# [('wname', 'Agnes Heinold'), ('info', 'place of birth, place of death'), ('cname', 'Germany')]
# [('wname', 'Agnes Herwarth von Bittenfeld'), ('info', 'place of death'), ('cname', 'Germany')]
# [('wname', 'Agnes Hoffmann'), ('info', 'place of birth'), ('cname', 'Germany')]
# [('wname', 'Agnes Mary Frances Duclaux'), ('info', 'place of death'), ('cname', 'France')]
# [('wname', 'Agnes Miegel'), ('info', 'place of death'), ('cname', 'Germany')]
# [('wname', 'Agnes Müller-von Brockhusen'), ('info', 'place of birth, place of death'), ('cname', 'Germany')]
# [('wname', 'Agnes Sapper'), ('info', 'place of birth, place of death'), ('cname', 'Germany')]
# [('wname', 'Agnes Taubert'), ('info', 'place of birth, place of death'), ('cname', 'Germany')]
# [('wname', 'Agnes Wendt'), ('info', 'place of birth'), ('cname', 'Germany')]
# [('wname', 'Agnes Wurmb'), ('info', 'place of birth, place of death'), ('cname', 'Germany')]
# [('wname', 'Agnes von Einsiedel'), ('info', 'place of birth'), ('cname', 'Germany')]
# [('wname', 'Agnes von Zahn-Harnack'), ('info', 'place of birth, place of death'), ('cname', 'Germany')]
# [('wname', 'Agnes-Marie Grisebach'), ('info', 'place of birth, place of death'), ('cname', 'Germany')]
# [('wname', 'Agnès Abécassis'), ('info', 'place of birth'), ('cname', 'France')]
# [('wname', 'Agnès Barron'), ('info', 'place of birth'), ('cname', 'France')]
# [('wname', 'Agnès Boucher'), ('info', 'place of birth'), ('cname', 'France')]
# [('wname', 'Agnès Desarthe'), ('info', 'place of birth'), ('cname', 'France')]
# [('wname', 'Agnès Giard'), ('info', 'place of birth'), ('cname', 'France')]
# [('wname', 'Agnès Jaoui'), ('info', 'place of birth'), ('cname', 'France')]
# [('wname', 'Agnès Laroche'), ('info', 'place of birth'), ('cname', 'France')]
# [('wname', 'Agnès Ledig'), ('info', 'place of birth'), ('cname', 'France')]
# [('wname', 'Agnès Mathieu-Daudé'), ('info', 'place of birth'), ('cname', 'France')]
# [('wname', 'Agnès Merlet'), ('info', 'place of birth'), ('cname', 'France')]
# [('wname', 'Agnès Michaux'), ('info', 'place of birth'), ('cname', 'France')]
# [('wname', 'Agnès Olive'), ('info', 'place of birth'), ('cname', 'France')]
# [('wname', 'Agnès Richomme'), ('info', 'place of birth, place of death'), ('cname', 'France')]
# [('wname', 'Agnès Rosenstiehl'), ('info', 'place of birth'), ('cname', 'France')]
# [('wname', 'Agnès Rouzier'), ('info', 'place of birth, place of death'), ('cname', 'France')]
# [('wname', 'Agnès Ruiz'), ('info', 'place of birth'), ('cname', 'France')]
# [('wname', 'Agnès Verlet'), ('info', 'place of birth'), ('cname', 'France')]
# [('wname', 'Agnès de La Gorce'), ('info', 'place of birth, place of death'), ('cname', 'France')]
# [('wname', 'Agosti Xaho'), ('info', 'place of birth, place of burial, place of death'), ('cname', 'France')]
# [('wname', 'Agripina Samper Agudelo'), ('info', 'place of death'), ('cname', 'France')]
# [('wname', "Agrippa d'Aubigné"), ('info', 'place of birth'), ('cname', 'France')]
# [('wname', 'Agustin Errotabehere'), ('info', 'place of birth'), ('cname', 'France')]
# [('wname', 'Agustín García Arrieta'), ('info', 'place of death'), ('cname', 'France')]
# [('wname', 'Agustín Gómez-Arcos'), ('info', 'place of burial, place of death'), ('cname', 'France')]
# [('wname', 'Agénor Altaroche'), ('info', 'place of birth, place of death'), ('cname', 'France')]
# [('wname', 'Agénor de Gasparin'), ('info', 'place of birth'), ('cname', 'France')]
# [('wname', 'Aharon Dadurian'), ('info', 'place of death'), ('cname', 'France')]
# [('wname', 'Ahasverus Fritsch'), ('info', 'place of birth, place of death'), ('cname', 'Germany')]
# [('wname', 'Ahmad Abdulal'), ('info', 'place of death'), ('cname', 'Germany')]
# [('wname', 'Ahmad von Denffer'), ('info', 'place of birth'), ('cname', 'Germany')]
# [('wname', 'Ahmadou Kourouma'), ('info', 'place of death'), ('cname', 'France')]
# [('wname', 'Ahmed Dramé'), ('info', 'place of birth'), ('cname', 'France')]
# [('wname', 'Ahmed Tidiane Cissé'), ('info', 'place of death'), ('cname', 'France')]
# [('wname', 'Ahmet Kaya'), ('info', 'place of burial, place of death'), ('cname', 'France')]
# [('wname', 'Ahne'), ('info', 'place of birth'), ('cname', 'Germany')]
# [('wname', 'Aimable Le Bot'), ('info', 'place of death'), ('cname', 'France')]
# [('wname', 'Aimeric de Peguilhan'), ('info', 'place of birth'), ('cname', 'France')]
# [('wname', 'Aimery de Comminges'), ('info', 'place of birth, place of death'), ('cname', 'France')]
# [('wname', 'Aimoin'), ('info', 'place of birth, place of death'), ('cname', 'France')]
# [('wname', 'Aimé Agussol'), ('info', 'place of birth, place of death'), ('cname', 'France')]
# [('wname', 'Aimé Blanc'), ('info', 'place of birth, place of death'), ('cname', 'France')]
# [('wname', 'Aimé Constantin'), ('info', 'place of birth, place of death'), ('cname', 'France')]
# [('wname', 'Aimé Césaire'), ('info', 'place of birth, place of death'), ('cname', 'France')]
# [('wname', 'Aimé Duval'), ('info', 'place of birth, place of burial, place of death'), ('cname', 'France')]
# [('wname', 'Aimé Giron'), ('info', 'place of birth, place of death'), ('cname', 'France')]
# [('wname', 'Aimé Guillon'), ('info', 'place of birth'), ('cname', 'France')]
# [('wname', 'Aimé Martin'), ('info', 'place of birth, place of death'), ('cname', 'France')]
# [('wname', 'Aimé Merlo'), ('info', 'place of birth, place of burial, place of death'), ('cname', 'France')]
# [('wname', 'Aimé Michel'), ('info', 'place of birth, place of death'), ('cname', 'France')]
# [('wname', 'Aimé Olivier de Sanderval'), ('info', 'place of birth, place of burial, place of death'), ('cname', 'France')]
# ...
# [('wname', 'Georges Limbour'), ('info', 'place of birth'), ('cname', 'France')]
# [('wname', 'Georges Lorin'), ('info', 'place of birth, place of death'), ('cname', 'France')]
# [('wname', 'Georges Lote'), ('info', 'place of birth, place of death'), ('cname', 'France')]
# [('wname', 'Georges Louza'), ('info', 'place of birth'), ('cname', 'France')]
# [('wname', 'Georges Lubin'), ('info', 'place of birth, place of death'), ('cname', 'France')]
# [('wname', 'Georges Magnane'), ('info', 'place of birth, place of death'), ('cname', 'France')]
# [('wname', 'Georges Maldague'), ('info', 'place of birth, place of death'), ('cname', 'France')]
# [('wname', 'Georges Mamy'), ('info', 'place of birth'), ('cname', 'France')]
# [('wname', 'Georges Martin'), ('info', 'place of birth, place of death'), ('cname', 'France')]
# [('wname', 'Georges Maurens'), ('info', 'place of birth'), ('cname', 'France')]
# [('wname', 'Georges Mauvois'), ('info', 'place of birth, place of death'), ('cname', 'France')]
# [('wname', 'Georges Michel'), ('info', 'place of birth, place of death'), ('cname', 'France')]
# [('wname', 'Georges Migot'), ('info', 'place of birth, place of death'), ('cname', 'France')]
# [('wname', 'Georges Minois'), ('info', 'place of birth'), ('cname', 'France')]
# [('wname', 'Georges Nardin'), ('info', 'place of birth'), ('cname', 'France')]
# [('wname', 'Georges Navel'), ('info', 'place of birth, place of death'), ('cname', 'France')]
# [('wname', 'Georges Neveux'), ('info', 'place of death'), ('cname', 'France')]
# [('wname', 'Georges Nivat'), ('info', 'place of birth'), ('cname', 'France')]
# [('wname', 'Georges Normandy'), ('info', 'place of birth, place of death'), ('cname', 'France')]
# [('wname', 'Georges Ohnet'), ('info', 'place of birth, place of burial, place of death'), ('cname', 'France')]
# [('wname', 'Georges Othily'), ('info', 'place of birth, place of death'), ('cname', 'France')]
# [('wname', 'Georges Ozaneaux'), ('info', 'place of birth, place of death'), ('cname', 'France')]
# [('wname', 'Georges Pacard'), ('info', 'place of death'), ('cname', 'France')]
# [('wname', 'Georges Palante'), ('info', 'place of birth, place of death'), ('cname', 'France')]
# [('wname', 'Georges Payelle'), ('info', 'place of birth, place of death'), ('cname', 'France')]
# [('wname', 'Georges Pellissier'), ('info', 'place of birth, place of death'), ('cname', 'France')]
# [('wname', 'Georges Perec'), ('info', 'place of birth, place of burial, place of death'), ('cname', 'France')]
# [('wname', 'Georges Perros'), ('info', 'place of birth, place of death'), ('cname', 'France')]
# [('wname', 'Georges Picard'), ('info', 'place of birth'), ('cname', 'France')]
# [('wname', 'Georges Pillement'), ('info', 'place of birth, place of death'), ('cname', 'France')]
# [('wname', 'Georges Pinault'), ('info', 'place of birth, place of death'), ('cname', 'France')]
# [('wname', 'Georges Politzer'), ('info', 'place of death'), ('cname', 'France')]
# [('wname', 'Georges Polti'), ('info', 'place of death'), ('cname', 'France')]
# [('wname', 'Georges Prévot'), ('info', 'place of birth, place of death'), ('cname', 'France')]
# [('wname', 'Georges Péladan'), ('info', 'place of birth'), ('cname', 'France')]
# [('wname', 'Georges Périn'), ('info', 'place of birth, place of death'), ('cname', 'France')]
# [('wname', 'Georges R. Reymond'), ('info', 'place of birth'), ('cname', 'Germany')]
# [('wname', 'Georges Rawiri'), ('info', 'place of death'), ('cname', 'France')]
# [('wname', 'Georges Renard'), ('info', 'place of birth, place of death'), ('cname', 'France')]
# [('wname', 'Georges Ribemont-Dessaignes'), ('info', 'place of birth, place of death'), ('cname', 'France')]
# [('wname', 'Georges Rodenbach'), ('info', 'place of burial, place of death'), ('cname', 'France')]
# [('wname', 'Georges Roditi'), ('info', 'place of birth, place of death'), ('cname', 'France')]
# [('wname', 'Georges Roussel'), ('info', 'place of birth, place of death'), ('cname', 'France')]
# [('wname', 'Georges Sadoul'), ('info', 'place of birth, place of death'), ('cname', 'France')]
# [('wname', 'Georges Saint-Bonnet'), ('info', 'place of birth, place of death'), ('cname', 'France')]
# [('wname', 'Georges Salan'), ('info', 'place of birth, place of death'), ('cname', 'France')]
# [('wname', 'Georges Sapède'), ('info', 'place of birth'), ('cname', 'France')]
# [('wname', 'Georges Schaffner'), ('info', 'place of birth'), ('cname', 'France')]
# [('wname', 'Georges Schehadé'), ('info', 'place of burial, place of death'), ('cname', 'France')]
# [('wname', 'Georges Sorel'), ('info', 'place of birth, place of burial, place of death'), ('cname', 'France')]
# [('wname', 'Georges Spetz'), ('info', 'place of birth, place of death'), ('cname', 'France')]
# [('wname', 'Georges Spillmann'), ('info', 'place of birth, place of death'), ('cname', 'France')]
# [('wname', 'Georges Spénale'), ('info', 'place of birth, place of death'), ('cname', 'France')]
# [('wname', 'Georges Tanneau'), ('info', 'place of birth, place of death'), ('cname', 'France')]
# [('wname', 'Georges Tarabichi'), ('info', 'place of death'), ('cname', 'France')]
# [('wname', 'Georges Thouret'), ('info', 'place of birth'), ('cname', 'France')]
# [('wname', 'Georges Touroude'), ('info', 'place of birth, place of death'), ('cname', 'France')]
# [('wname', 'Georges Trillat'), ('info', 'place of birth'), ('cname', 'France')]
# [('wname', 'Georges Vedel'), ('info', 'place of birth, place of burial, place of death'), ('cname', 'France')]
# [('wname', 'Georges Vidal'), ('info', 'place of birth, place of death'), ('cname', 'France')]
# [('wname', 'Georges Walter'), ('info', 'place of death'), ('cname', 'France')]
# [('wname', 'Georges Weill'), ('info', 'place of birth, place of burial, place of death'), ('cname', 'France')]
# [('wname', 'Georges Wolinski'), ('info', 'place of burial, place of death'), ('cname', 'France')]
# [('wname', 'Georges Yver'), ('info', 'place of birth, place of death'), ('cname', 'France')]
# [('wname', 'Georges Zink'), ('info', 'place of birth, place of death'), ('cname', 'France')]
# [('wname', "Georges d'Esparbès"), ('info', 'place of birth, place of death'), ('cname', 'France')]
# [('wname', 'Georges de Bièvre'), ('info', 'place of birth'), ('cname', 'France')]
# [('wname', 'Georges de Bièvre'), ('info', 'place of death'), ('cname', 'Germany')]
# [('wname', 'Georges de Brébeuf'), ('info', 'place of birth, place of death'), ('cname', 'France')]
# [('wname', 'Georges de Lys'), ('info', 'place of birth, place of death'), ('cname', 'France')]
# [('wname', 'Georges de Nantes'), ('info', 'place of birth, place of death'), ('cname', 'France')]
# [('wname', 'Georges de Plinval'), ('info', 'place of birth'), ('cname', 'France')]
# [('wname', 'Georges de Porto-Riche'), ('info', 'place of birth, place of burial, place of death'), ('cname', 'France')]
# [('wname', 'Georges de Roquette-Buisson'), ('info', 'place of birth, place of death'), ('cname', 'France')]
# [('wname', 'Georges de Scudéry'), ('info', 'place of birth, place of death'), ('cname', 'France')]
# [('wname', 'Georges de Soultrait'), ('info', 'place of birth, place of death'), ('cname', 'France')]
# [('wname', 'Georges d’Heylli'), ('info', 'place of birth, place of death'), ('cname', 'France')]
# [('wname', 'Georges, Vicomte de Mauduit'), ('info', 'place of birth'), ('cname', 'France')]
# [('wname', 'Georges, Vicomte de Mauduit'), ('info', 'place of death'), ('cname', 'Germany')]
# [('wname', 'Georges-André Vachon'), ('info', 'place of birth'), ('cname', 'France')]
# [('wname', 'Georges-Arthur Goldschmidt'), ('info', 'place of birth'), ('cname', 'Germany')]
# [('wname', 'Georges-Emmanuel Clancier'), ('info', 'place of birth, place of burial, place of death'), ('cname', 'France')]
# [('wname', 'Georges-Eugène Bertin'), ('info', 'place of burial, place of death'), ('cname', 'France')]
# [('wname', 'Georges-Gustave Toudouze'), ('info', 'place of birth, place of death'), ('cname', 'France')]
# [('wname', 'Georges-Jean Arnaud'), ('info', 'place of birth, place of death'), ('cname', 'France')]
# [('wname', 'Georges-L. Godeau'), ('info', 'place of birth, place of death'), ('cname', 'France')]
# [('wname', 'Georges-Olivier Châteaureynaud'), ('info', 'place of birth'), ('cname', 'France')]
# [('wname', 'Georges-Patrick Gleize'), ('info', 'place of birth'), ('cname', 'France')]
# [('wname', 'Georges-Paul Cuny'), ('info', 'place of birth'), ('cname', 'France')]
# [('wname', 'Georgette Dreyfus-Guéguen'), ('info', 'place of birth, place of death'), ('cname', 'France')]
# [('wname', 'Georgette Leblanc'), ('info', 'place of birth, place of death'), ('cname', 'France')]
# [('wname', 'Georgette Vallejo'), ('info', 'place of birth'), ('cname', 'France')]
# [('wname', 'Georgette de Montenay'), ('info', 'place of birth, place of death'), ('cname', 'France')]
# [('wname', 'Georgi Vladimov'), ('info', 'place of death'), ('cname', 'Germany')]
# [('wname', 'Georgia Caldera'), ('info', 'place of birth'), ('cname', 'France')]
# [('wname', 'Georgie Kondarji'), ('info', 'place of death'), ('cname', 'France')]
# [('wname', 'Georgine Köhler'), ('info', 'place of birth'), ('cname', 'Germany')]
# [('wname', 'Georgios Vougiouklakes'), ('info', 'place of death'), ('cname', 'France')]
# [('wname', 'Georgios Vrisimitzakis'), ('info', 'place of death'), ('cname', 'France')]
# [('wname', 'Georgius Benedicti'), ('info', 'place of death'), ('cname', 'Germany')]
# [('wname', 'Georgius Hornius'), ('info', 'place of birth'), ('cname', 'Germany')]
# [('wname', 'Georgius Trajectinus'), ('info', 'place of birth'), ('cname', 'Germany')]
# [('wname', 'Georgiy Peskov'), ('info', 'place of death'), ('cname', 'France')]
# [('wname', 'Georgy Adamovich'), ('info', 'place of burial, place of death'), ('cname', 'France')]
# [('wname', 'Georgy Ivanov'), ('info', 'place of burial, place of death'), ('cname', 'France')]
# [('wname', 'Gerald Drews'), ('info', 'place of birth'), ('cname', 'Germany')]
# [('wname', 'Gerald Fränkl'), ('info', 'place of birth'), ('cname', 'Germany')]
# [('wname', 'Gerald Grote'), ('info', 'place of birth'), ('cname', 'Germany')]
# [('wname', 'Gerald Götting'), ('info', 'place of birth, place of burial, place of death'), ('cname', 'Germany')]
# [('wname', 'Gerald Huber'), ('info', 'place of birth'), ('cname', 'Germany')]
# [('wname', 'Gerald Höfer'), ('info', 'place of birth'), ('cname', 'Germany')]
# [('wname', 'Gerald Messadié'), ('info', 'place of death'), ('cname', 'France')]
# [('wname', 'Gerald Neumann'), ('info', 'place of birth'), ('cname', 'Germany')]
# [('wname', 'Gerald P. R. Martin'), ('info', 'place of birth'), ('cname', 'Germany')]
# [('wname', 'Gerald Pinkenburg'), ('info', 'place of birth'), ('cname', 'Germany')]
# [('wname', 'Gerald Sommer'), ('info', 'place of birth'), ('cname', 'Germany')]
# [('wname', 'Gerald Uhlig-Romero'), ('info', 'place of birth'), ('cname', 'Germany')]
# [('wname', 'Gerald Zschorsch'), ('info', 'place of birth'), ('cname', 'Germany')]
# [('wname', 'Gerard Braunthal'), ('info', 'place of birth'), ('cname', 'Germany')]
# [('wname', 'Gerard Hoffnung'), ('info', 'place of birth'), ('cname', 'Germany')]
# [('wname', 'Gerardus Vossius'), ('info', 'place of birth'), ('cname', 'Germany')]
# [('wname', 'Gerasimos Vokos'), ('info', 'place of death'), ('cname', 'France')]
# [('wname', 'Gerat Nagora'), ('info', 'place of death'), ('cname', 'Germany')]
# [('wname', 'Gerbert Grohmann'), ('info', 'place of death'), ('cname', 'Germany')]
# [('wname', 'Gerbert de Montreuil'), ('info', 'place of birth'), ('cname', 'France')]
# [('wname', 'Gerd B. Achenbach'), ('info', 'place of birth'), ('cname', 'Germany')]
# [('wname', 'Gerd Bahr'), ('info', 'place of birth'), ('cname', 'Germany')]
# [('wname', 'Gerd Bedszent'), ('info', 'place of birth'), ('cname', 'Germany')]
# [('wname', 'Gerd Berendt'), ('info', 'place of birth'), ('cname', 'Germany')]
# [('wname', 'Gerd Berghofer'), ('info', 'place of birth'), ('cname', 'Germany')]
# [('wname', 'Gerd Billing'), ('info', 'place of birth'), ('cname', 'Germany')]
# [('wname', 'Gerd Brudermüller'), ('info', 'place of birth'), ('cname', 'Germany')]
# [('wname', 'Gerd Bucerius'), ('info', 'place of birth, place of death'), ('cname', 'Germany')]
# [('wname', 'Gerd Buskamp'), ('info', 'place of birth'), ('cname', 'Germany')]
# [('wname', 'Gerd Busse'), ('info', 'place of birth'), ('cname', 'Germany')]
# [('wname', 'Gerd Buurmann'), ('info', 'place of birth'), ('cname', 'Germany')]
# [('wname', 'Gerd Constapel'), ('info', 'place of birth'), ('cname', 'Germany')]
# [('wname', 'Gerd Dembowski'), ('info', 'place of birth'), ('cname', 'Germany')]
# [('wname', 'Gerd Dudenhöffer'), ('info', 'place of birth'), ('cname', 'Germany')]
# [('wname', 'Gerd Eggers'), ('info', 'place of birth'), ('cname', 'Germany')]
# [('wname', 'Gerd Eilers'), ('info', 'place of death'), ('cname', 'Germany')]
# [('wname', 'Gerd Eversberg'), ('info', 'place of birth'), ('cname', 'Germany')]
# [('wname', 'Gerd F. Schultze'), ('info', 'place of birth'), ('cname', 'Germany')]
# [('wname', 'Gerd Fischer'), ('info', 'place of birth'), ('cname', 'Germany')]
# [('wname', 'Gerd Forster'), ('info', 'place of birth'), ('cname', 'Germany')]
# [('wname', 'Gerd Frey'), ('info', 'place of birth'), ('cname', 'Germany')]
# [('wname', 'Gerd Fuchs'), ('info', 'place of birth'), ('cname', 'Germany')]
# [('wname', 'Gerd Gaiser'), ('info', 'place of birth, place of death'), ('cname', 'Germany')]
# [('wname', 'Gerd Ganteför'), ('info', 'place of birth'), ('cname', 'Germany')]
# [('wname', 'Gerd Hafner'), ('info', 'place of birth, place of death'), ('cname', 'Germany')]
# [('wname', 'Gerd Henniger'), ('info', 'place of birth'), ('cname', 'Germany')]
# [('wname', 'Gerd Hergen Lübben'), ('info', 'place of birth'), ('cname', 'Germany')]
# [('wname', 'Gerd Herrmann'), ('info', 'place of birth, place of death'), ('cname', 'Germany')]
# [('wname', 'Gerd Heuvel'), ('info', 'place of birth'), ('cname', 'Germany')]
# [('wname', 'Gerd Holzheimer'), ('info', 'place of birth'), ('cname', 'Germany')]
# [('wname', 'Gerd Hupperich'), ('info', 'place of birth'), ('cname', 'Germany')]
# [('wname', 'Gerd Imbsweiler'), ('info', 'place of birth'), ('cname', 'Germany')]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-3736072fcc8c> in <module>
#      23
#      24 print("Results")
# ---> 25 run_query(queryString)
#
# <ipython-input-1-c37502d8aa04> in run_query(queryString)
#      28
#      29        for bindings in json_results['results']['bindings']:
# ---> 30           print( [ (var, value['value'])  for var, value in bindings.items() ] )
#      31
#      32        return len(json_results['results']['bindings'])
#
# ~/miniconda3/lib/python3.7/site-packages/ipykernel/iostream.py in write(self, string)
#     400             is_child = (not self._is_master_process())
#     401             # only touch the buffer in the IO thread to avoid races
# --> 402             self.pub_thread.schedule(lambda : self._buffer.write(string))
#     403             if is_child:
#     404                 # mp.Pool cannot be trusted to flush promptly (or ever),
#
# ~/miniconda3/lib/python3.7/site-packages/ipykernel/iostream.py in schedule(self, f)
#     201             self._events.append(f)
#     202             # wake event thread (message content is ignored)
# --> 203             self._event_pipe.send(b'')
#     204         else:
#     205             f()
#
# ~/miniconda3/lib/python3.7/site-packages/zmq/sugar/socket.py in send(self, data, flags, copy, track, routing_id, group)
#     414                                  copy_threshold=self.copy_threshold)
#     415             data.group = group
# --> 416         return super(Socket, self).send(data, flags=flags, copy=copy, track=track)
#     417
#     418     def send_multipart(self, msg_parts, flags=0, copy=True, track=False, **kwargs):
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._send_copy()
#
# ~/miniconda3/lib/python3.7/site-packages/zmq/backend/cython/checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:

# %% [markdown]
# Here we have an example of a poet or writer with different country for the place of birth, death or burial
#
# [('wname', 'Albert Schmitt'), ('info', 'place of death'), ('cname', 'Germany')]
# [('wname', 'Albert Schmitt'), ('info', 'place of birth, place of burial'), ('cname', 'France')]

# %% [markdown]
# ## Task 4
#
# 4. Analyze cities across the two countries
#
#     4.1 Is there any poet for which the birth place and the place of burial are located in the same city either in Germany or France?
#
#     4.2 Which cities host the place of birth of the larger number of poets or writers across the two countries?
#
#     4.3 What are the top 3 cities in each country that you could visit? Based on what criteria?

# %% [markdown]
# ### Task 4.1
# 4.1 Is there any poet for which the birth place and the place of burial are located in the same city either in Germany or France?

# %% [markdown]
# #### Comment
#
# Let's try to find the city at which a place belongs taking as an example the Montparnasse Cemetery (wd:Q272208), we know that is in Paris (wd:Q90) but are there any links between the two nodes?

# %%
#From Montparnasse Cemetery to Paris
queryString = """
SELECT ?oname ?p 
WHERE { 

wd:Q272208 ?p wd:Q90 .

# ?p <http://schema.org/name> ?pname .
#OPTIONAL {?obj <http://schema.org/name> ?oname }.
} 
"""

print("Results")
run_query(queryString)
# Out:
# Results
# Empty
# 0

# %%
#From Paris to Montparnasse Cemetery
queryString = """
SELECT ?oname ?p 
WHERE { 

wd:Q90 ?p wd:Q272208 .

# ?p <http://schema.org/name> ?pname .
#OPTIONAL {?obj <http://schema.org/name> ?oname }.
} 
"""

print("Results")
run_query(queryString)
# Out:
# Results
# Empty
# 0

# %% [markdown]
# #### Comment
# There are no direct links between the two nodes let's try to find other connection that can link a place with their city:
#
# | IRI           | Description   | Role      |
# | -----------   | -----------   |-----------|
# | `wdt:P131`     | located in the administrative territorial entity       | predicate |
# | `wd:Q187153`     | 14th arrondissement of Paris        | node |
#
# Looking at the node "14th arrondissement of Paris" I can suppose that it can have some relations with the "Paris" (wd:Q90) node

# %%
#Let's check the outgoing edges of "14th arrondissement of Paris"
queryString = """
SELECT ?pname ?oname ?p 
WHERE { 

wd:Q187153 ?p ?obj .

# ?p <http://schema.org/name> ?pname .
OPTIONAL {?obj <http://schema.org/name> ?oname }.
} 
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('pname', 'shares border with'), ('oname', '13th arrondissement of Paris'), ('p', 'http://www.wikidata.org/prop/direct/P47')]
# [('pname', 'replaces'), ('oname', 'former 12th arrondissement of Paris'), ('p', 'http://www.wikidata.org/prop/direct/P1365')]
# [('pname', 'country'), ('oname', 'France'), ('p', 'http://www.wikidata.org/prop/direct/P17')]
# [('pname', 'shares border with'), ('oname', '5th arrondissement of Paris'), ('p', 'http://www.wikidata.org/prop/direct/P47')]
# [('pname', 'shares border with'), ('oname', '6th arrondissement of Paris'), ('p', 'http://www.wikidata.org/prop/direct/P47')]
# [('pname', 'instance of'), ('oname', 'municipal arrondissement'), ('p', 'http://www.wikidata.org/prop/direct/P31')]
# [('pname', 'located in the administrative territorial entity'), ('oname', 'Paris'), ('p', 'http://www.wikidata.org/prop/direct/P131')]
# [('pname', 'contains administrative territorial entity'), ('oname', 'Montparnasse'), ('p', 'http://www.wikidata.org/prop/direct/P150')]
# [('pname', 'contains administrative territorial entity'), ('oname', 'Petit-Montrouge'), ('p', 'http://www.wikidata.org/prop/direct/P150')]
# [('pname', 'contains administrative territorial entity'), ('oname', 'Plaisance'), ('p', 'http://www.wikidata.org/prop/direct/P150')]
# [('pname', 'contains administrative territorial entity'), ('oname', 'Parc-de-Montsouris'), ('p', 'http://www.wikidata.org/prop/direct/P150')]
# [('pname', 'replaces'), ('oname', 'Vanves'), ('p', 'http://www.wikidata.org/prop/direct/P1365')]
# [('pname', 'replaces'), ('oname', 'Montrouge'), ('p', 'http://www.wikidata.org/prop/direct/P1365')]
# [('pname', 'replaces'), ('oname', 'Gentilly'), ('p', 'http://www.wikidata.org/prop/direct/P1365')]
# [('pname', 'shares border with'), ('oname', '15th arrondissement of Paris'), ('p', 'http://www.wikidata.org/prop/direct/P47')]
# [('pname', 'replaces'), ('oname', 'Vaugirard'), ('p', 'http://www.wikidata.org/prop/direct/P1365')]
# [('pname', 'category for films shot at this location'), ('oname', 'Category:Films shot in the 14th arrondissement of Paris'), ('p', 'http://www.wikidata.org/prop/direct/P1740')]
# [('pname', 'head of government'), ('oname', 'Carine Petit'), ('p', 'http://www.wikidata.org/prop/direct/P6')]
# [('pname', 'office held by head of government'), ('oname', 'Mayor of 14th arrondissement of Paris'), ('p', 'http://www.wikidata.org/prop/direct/P1313')]
# [('pname', "topic's main category"), ('oname', 'Category:14th arrondissement of Paris'), ('p', 'http://www.wikidata.org/prop/direct/P910')]
# [('pname', 'category for maps'), ('oname', 'Category:Maps of Paris 14e arrondissement'), ('p', 'http://www.wikidata.org/prop/direct/P7867')]
# [('pname', 'category for people who died here'), ('oname', 'Category:Deaths in 14th arrondissement of Paris'), ('p', 'http://www.wikidata.org/prop/direct/P1465')]
# [('pname', 'population'), ('p', 'http://www.wikidata.org/prop/direct/P1082')]
# [('pname', 'category for people born here'), ('p', 'http://www.wikidata.org/prop/direct/P1464')]
# [('pname', 'GeoNames ID'), ('p', 'http://www.wikidata.org/prop/direct/P1566')]
# [('pname', 'detail map'), ('p', 'http://www.wikidata.org/prop/direct/P1621')]
# [('pname', 'image'), ('p', 'http://www.wikidata.org/prop/direct/P18')]
# [('pname', 'Twitter username'), ('p', 'http://www.wikidata.org/prop/direct/P2002')]
# [('pname', 'area'), ('p', 'http://www.wikidata.org/prop/direct/P2046')]
# [('pname', 'ISNI'), ('p', 'http://www.wikidata.org/prop/direct/P213')]
# [('pname', 'VIAF ID'), ('p', 'http://www.wikidata.org/prop/direct/P214')]
# [('pname', 'GND ID'), ('p', 'http://www.wikidata.org/prop/direct/P227')]
# [('pname', 'locator map image'), ('p', 'http://www.wikidata.org/prop/direct/P242')]
# [('pname', 'Bibliothèque nationale de France ID'), ('p', 'http://www.wikidata.org/prop/direct/P268')]
# [('pname', 'postal code'), ('p', 'http://www.wikidata.org/prop/direct/P281')]
# [('pname', 'Commons category'), ('p', 'http://www.wikidata.org/prop/direct/P373')]
# [('pname', 'INSEE municipality code'), ('p', 'http://www.wikidata.org/prop/direct/P374')]
# [('pname', 'OpenStreetMap relation ID'), ('p', 'http://www.wikidata.org/prop/direct/P402')]
# [('pname', 'archINFORM location ID'), ('p', 'http://www.wikidata.org/prop/direct/P5573')]
# [('pname', 'inception'), ('p', 'http://www.wikidata.org/prop/direct/P571')]
# [('pname', 'annual number of weddings'), ('p', 'http://www.wikidata.org/prop/direct/P5982')]
# [('pname', 'annual number of weddings'), ('p', 'http://www.wikidata.org/prop/direct/P5982')]
# [('pname', 'annual number of weddings'), ('p', 'http://www.wikidata.org/prop/direct/P5982')]
# [('pname', 'annual number of weddings'), ('p', 'http://www.wikidata.org/prop/direct/P5982')]
# [('pname', 'annual number of weddings'), ('p', 'http://www.wikidata.org/prop/direct/P5982')]
# [('pname', 'annual number of weddings'), ('p', 'http://www.wikidata.org/prop/direct/P5982')]
# [('pname', 'annual number of weddings'), ('p', 'http://www.wikidata.org/prop/direct/P5982')]
# [('pname', 'annual number of weddings'), ('p', 'http://www.wikidata.org/prop/direct/P5982')]
# [('pname', 'annual number of weddings'), ('p', 'http://www.wikidata.org/prop/direct/P5982')]
# [('pname', 'annual number of weddings'), ('p', 'http://www.wikidata.org/prop/direct/P5982')]
# [('pname', 'annual number of weddings'), ('p', 'http://www.wikidata.org/prop/direct/P5982')]
# [('pname', 'Freebase ID'), ('p', 'http://www.wikidata.org/prop/direct/P646')]
# [('pname', 'WorldCat Identities ID'), ('p', 'http://www.wikidata.org/prop/direct/P7859')]
# [('pname', 'official website'), ('p', 'http://www.wikidata.org/prop/direct/P856')]
# [('pname', 'social media followers'), ('p', 'http://www.wikidata.org/prop/direct/P8687')]
# [('pname', 'GADM ID'), ('p', 'http://www.wikidata.org/prop/direct/P8714')]
# [('pname', 'coat of arms image'), ('p', 'http://www.wikidata.org/prop/direct/P94')]
# [('pname', 'page banner'), ('p', 'http://www.wikidata.org/prop/direct/P948')]
# 58

# %% [markdown]
# #### Comment
#
# We have discovered that through "located in the administrative territorial entity" (wdt:P131) property the "14th arrondissement of Paris" node is linked with the "Paris" node.
# So to be sure to discover in the correct way the belonging to a city of a place I search for 0 or more occurrencies of the property (wdt:P131) between the place of burial node and the place of birth node (if the property occurs 0 times it means that the place of birth and the place of burial are the same and that the place can coincide with a city).

# %%
#Let's check if a place of burial is linked through one or more "located in the administrative territorial entity" with a place of birth
queryString = """
SELECT DISTINCT ?pname ?burial ?birth ?cname
WHERE { 

# ?per wdt:P106 ?job ; 
    # ?pobu ?bu ;
    # ?pobi ?bi .
# ?bu (wdt:P131)* ?bi ;
    wdt:P17 ?c .
# ?bi wdt:P17 ?c .

FILTER(?job = wd:Q49757).
FILTER(?pobu = wdt:P119 && ?pobi = wdt:P19).
FILTER(?c = wd:Q142 || ?c = wd:Q183).

# ?per <http://schema.org/name> ?pname .
# ?bu <http://schema.org/name> ?burial .
# ?bi <http://schema.org/name> ?birth .
# ?c <http://schema.org/name> ?cname .
}
ORDER BY ASC (?pname)
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('pname', 'Adolphe Lacuzon'), ('burial', 'Cimetière Saint-Jean de Valenciennes'), ('birth', 'Valenciennes'), ('cname', 'France')]
# [('pname', 'Adélaïde Dufrénoy'), ('burial', 'Père Lachaise Cemetery'), ('birth', 'Paris'), ('cname', 'France')]
# [('pname', "Adélaïde-Louise d'Eckmühl de Blocqueville"), ('burial', 'Père Lachaise Cemetery'), ('birth', 'Paris'), ('cname', 'France')]
# [('pname', 'Agathe-Sophie Sasserno'), ('burial', 'Cimetière du Château'), ('birth', 'Nice'), ('cname', 'France')]
# [('pname', 'Alain Jouffroy'), ('burial', 'Père Lachaise Cemetery'), ('birth', 'Paris'), ('cname', 'France')]
# [('pname', 'Albert Saisset'), ('burial', 'Cemetery Saint-Martin de Perpignan'), ('birth', 'Perpignan'), ('cname', 'France')]
# [('pname', 'Albert Tinchant'), ('burial', 'Père Lachaise Cemetery'), ('birth', 'Paris'), ('cname', 'France')]
# [('pname', 'Alexandre Desrousseaux'), ('burial', 'cimetière de l’Est'), ('birth', 'Lille'), ('cname', 'France')]
# [('pname', 'Alfred Le Roux'), ('burial', 'Père Lachaise Cemetery'), ('birth', 'Paris'), ('cname', 'France')]
# [('pname', 'Alfred de Musset'), ('burial', 'Père Lachaise Cemetery'), ('birth', 'Paris'), ('cname', 'France')]
# [('pname', 'Alphonse Brot'), ('burial', 'Père Lachaise Cemetery'), ('birth', 'Paris'), ('cname', 'France')]
# [('pname', 'Alphonse Brot'), ('burial', 'Montmartre Cemetery'), ('birth', 'Paris'), ('cname', 'France')]
# [('pname', 'Alphonse Germain-Lacour'), ('burial', 'Moulins-sur-Orne'), ('birth', 'Moulins-sur-Orne'), ('cname', 'France')]
# [('pname', 'André Gill'), ('burial', 'Père Lachaise Cemetery'), ('birth', 'Paris'), ('cname', 'France')]
# [('pname', 'André Pieyre de Mandiargues'), ('burial', 'Père Lachaise Cemetery'), ('birth', 'Paris'), ('cname', 'France')]
# [('pname', 'André-Antoine Ravrio'), ('burial', 'Père Lachaise Cemetery'), ('birth', 'Paris'), ('cname', 'France')]
# [('pname', 'Anna de Noailles'), ('burial', 'Père Lachaise Cemetery'), ('birth', 'Paris'), ('cname', 'France')]
# [('pname', 'Antonin Artaud'), ('burial', 'Saint Pierre Cemetery'), ('birth', 'Marseille'), ('cname', 'France')]
# [('pname', "Armand d'Artois"), ('burial', 'Père Lachaise Cemetery'), ('birth', 'Paris'), ('cname', 'France')]
# [('pname', 'August Hermann Niemeyer'), ('burial', 'Stadtgottesacker'), ('birth', 'Halle (Saale)'), ('cname', 'Germany')]
# [('pname', 'Auguste Magdalene of Hessen-Darmstadt'), ('burial', 'Stadtkirche Darmstadt'), ('birth', 'Darmstadt'), ('cname', 'Germany')]
# [('pname', 'Bernard Heidsieck'), ('burial', 'Père Lachaise Cemetery'), ('birth', 'Paris'), ('cname', 'France')]
# [('pname', 'Boris Vian'), ('burial', "Ville-d'Avray"), ('birth', "Ville-d'Avray"), ('cname', 'France')]
# [('pname', 'Camille Doucet'), ('burial', 'Montparnasse Cemetery'), ('birth', 'Paris'), ('cname', 'France')]
# [('pname', 'Carl Spitzweg'), ('burial', 'Alter Südfriedhof'), ('birth', 'Munich'), ('cname', 'Germany')]
# [('pname', 'Charles Baudelaire'), ('burial', 'Montparnasse Cemetery'), ('birth', 'Paris'), ('cname', 'France')]
# [('pname', 'Charles Bécas'), ('burial', 'Ainhoa'), ('birth', 'Ainhoa'), ('cname', 'France')]
# [('pname', 'Charles Coligny'), ('burial', 'Père Lachaise Cemetery'), ('birth', 'Paris'), ('cname', 'France')]
# [('pname', 'Charles Marie René Leconte de Lisle'), ('burial', 'Cimetière marin de Saint-Paul'), ('birth', 'Saint-Paul'), ('cname', 'France')]
# [('pname', 'Charles Rabourdin'), ('burial', 'Cimetière Nord de Melun'), ('birth', 'Melun'), ('cname', 'France')]
# [('pname', 'Charles Valois'), ('burial', 'Batignolles Cemetery'), ('birth', 'Paris'), ('cname', 'France')]
# [('pname', 'Charles-Louis Philippe'), ('burial', 'Cérilly'), ('birth', 'Cérilly'), ('cname', 'France')]
# [('pname', 'Claude Visinet des Presles'), ('burial', 'Père Lachaise Cemetery'), ('birth', 'Paris'), ('cname', 'France')]
# [('pname', 'Cäsar Flaischlen'), ('burial', 'Pragfriedhof Stuttgart'), ('birth', 'Stuttgart'), ('cname', 'Germany')]
# [('pname', 'Céline Varenne'), ('burial', 'Père Lachaise Cemetery'), ('birth', 'Paris'), ('cname', 'France')]
# [('pname', 'Daniel Anselme'), ('burial', 'Père Lachaise Cemetery'), ('birth', 'Paris'), ('cname', 'France')]
# [('pname', 'Edgar Degas'), ('burial', 'Montmartre Cemetery'), ('birth', 'Paris'), ('cname', 'France')]
# [('pname', 'Edmond Cottinet'), ('burial', 'Père Lachaise Cemetery'), ('birth', 'Paris'), ('cname', 'France')]
# [('pname', 'Edmond Rostand'), ('burial', 'Saint Pierre Cemetery'), ('birth', 'Marseille'), ('cname', 'France')]
# [('pname', 'Edouard Plouvier'), ('burial', 'Père Lachaise Cemetery'), ('birth', 'Paris'), ('cname', 'France')]
# [('pname', 'Ehrenfried Stoeber'), ('burial', 'Cimetière Saint-Gall de Strasbourg'), ('birth', 'Strasbourg'), ('cname', 'France')]
# [('pname', 'Emanuel Geibel'), ('burial', 'Burgtorfriedhof'), ('birth', 'Lübeck'), ('cname', 'Germany')]
# [('pname', 'Enguerrand Homps'), ('burial', "Cimetière de l'Ouest"), ('birth', 'Reims'), ('cname', 'France')]
# [('pname', 'Ernest Hamel'), ('burial', 'Père Lachaise Cemetery'), ('birth', 'Paris'), ('cname', 'France')]
# [('pname', 'Ernest Louis, Grand Duke of Hesse'), ('burial', 'Darmstadt'), ('birth', 'Darmstadt'), ('cname', 'Germany')]
# [('pname', 'Ernst Meister'), ('burial', 'Delstern'), ('birth', 'Hagen'), ('cname', 'Germany')]
# [('pname', 'Erwan ar Moal'), ('burial', 'Coadout'), ('birth', 'Coadout'), ('cname', 'France')]
# [('pname', 'Eugen Roth'), ('burial', 'Friedhof Nymphenburg'), ('birth', 'Munich'), ('cname', 'Germany')]
# [('pname', 'Eugène Bizeau'), ('burial', 'Véretz'), ('birth', 'Véretz'), ('cname', 'France')]
# [('pname', 'Eugène Dayot'), ('burial', 'Cimetière marin de Saint-Paul'), ('birth', 'Saint-Paul'), ('cname', 'France')]
# [('pname', 'Eugène Pottier'), ('burial', 'Père Lachaise Cemetery'), ('birth', 'Paris'), ('cname', 'France')]
# [('pname', 'Eusèbe de Salverte'), ('burial', 'Père Lachaise Cemetery'), ('birth', 'Paris'), ('cname', 'France')]
# [('pname', 'Fernand Desnoyers'), ('burial', 'Montparnasse Cemetery'), ('birth', 'Paris'), ('cname', 'France')]
# [('pname', 'Francis Picabia'), ('burial', 'Montmartre Cemetery'), ('birth', 'Paris'), ('cname', 'France')]
# [('pname', 'Francis Tourte'), ('burial', 'Père Lachaise Cemetery'), ('birth', 'Paris'), ('cname', 'France')]
# [('pname', 'Franzjosef Schneider'), ('burial', 'Neuer Friedhof (Bad Honnef)'), ('birth', 'Bad Honnef'), ('cname', 'Germany')]
# [('pname', 'François Coppée'), ('burial', 'Montparnasse Cemetery'), ('birth', 'Paris'), ('cname', 'France')]
# [('pname', 'François Dufrêne'), ('burial', 'Montparnasse Cemetery'), ('birth', '14th arrondissement of Paris'), ('cname', 'France')]
# [('pname', 'François-Auguste Parseval-Grandmaison'), ('burial', 'Père Lachaise Cemetery'), ('birth', 'Paris'), ('cname', 'France')]
# [('pname', 'François-René de Chateaubriand'), ('burial', 'tomb of Chateaubriand'), ('birth', 'Saint-Malo'), ('cname', 'France')]
# [('pname', "François-Thomas-Marie de Baculard d'Arnaud"), ('burial', 'Père Lachaise Cemetery'), ('birth', 'Paris'), ('cname', 'France')]
# [('pname', 'Fritz Kieffer'), ('burial', 'Cimetière Saint-Gall de Strasbourg'), ('birth', 'Strasbourg'), ('cname', 'France')]
# [('pname', 'Frédéric de Courcy'), ('burial', 'Père Lachaise Cemetery'), ('birth', 'Paris'), ('cname', 'France')]
# [('pname', 'Gaston Bachelard'), ('burial', 'Bar-sur-Aube'), ('birth', 'Bar-sur-Aube'), ('cname', 'France')]
# [('pname', 'Gaston Gérardot de Sermoise'), ('burial', 'Père Lachaise Cemetery'), ('birth', 'Paris'), ('cname', 'France')]
# [('pname', 'Gaston de Montheau'), ('burial', 'Père Lachaise Cemetery'), ('birth', 'Paris'), ('cname', 'France')]
# [('pname', 'Gauthier-Ferrières'), ('burial', 'Père Lachaise Cemetery'), ('birth', 'Paris'), ('cname', 'France')]
# [('pname', 'Georg Thurmair'), ('burial', 'Munich Waldfriedhof'), ('birth', 'Munich'), ('cname', 'Germany')]
# [('pname', 'Gisèle Barbotin'), ('burial', 'Argenton-sur-Creuse'), ('birth', 'Argenton-sur-Creuse'), ('cname', 'France')]
# [('pname', 'Gustav Adolph, Duke of Mecklenburg-Güstrow'), ('burial', 'Güstrow Cathedral'), ('birth', 'Güstrow'), ('cname', 'Germany')]
# [('pname', 'Gustav Pfizer'), ('burial', 'Pragfriedhof Stuttgart'), ('birth', 'Stuttgart'), ('cname', 'Germany')]
# [('pname', 'Gustav Schwab'), ('burial', 'Hoppenlau Cemetery'), ('birth', 'Stuttgart'), ('cname', 'Germany')]
# [('pname', 'Gérard de Nerval'), ('burial', 'Père Lachaise Cemetery'), ('birth', 'Paris'), ('cname', 'France')]
# [('pname', 'Günter Bruno Fuchs'), ('burial', 'Columbiadamm Cemetery'), ('birth', 'Berlin'), ('cname', 'Germany')]
# [('pname', 'Hanns Heinz Ewers'), ('burial', 'Nordfriedhof (Düsseldorf)'), ('birth', 'Düsseldorf'), ('cname', 'Germany')]
# [('pname', 'Hans Sachs'), ('burial', 'Johannisfriedhof'), ('birth', 'Nuremberg'), ('cname', 'Germany')]
# [('pname', 'Heinrich Hoffmann'), ('burial', 'Frankfurt Main Cemetery'), ('birth', 'Frankfurt am Main'), ('cname', 'Germany')]
# [('pname', 'Henri Auguste Barbier'), ('burial', 'Père Lachaise Cemetery'), ('birth', 'Paris'), ('cname', 'France')]
# [('pname', 'Henri Bouvelet'), ('burial', 'Père Lachaise Cemetery'), ('birth', 'Paris'), ('cname', 'France')]
# [('pname', 'Henri Lacretelle'), ('burial', 'Père Lachaise Cemetery'), ('birth', 'Paris'), ('cname', 'France')]
# [('pname', 'Henri Meschonnic'), ('burial', 'Père Lachaise Cemetery'), ('birth', 'Paris'), ('cname', 'France')]
# [('pname', 'Henri Murger'), ('burial', 'Montmartre Cemetery'), ('birth', 'Paris'), ('cname', 'France')]
# [('pname', 'Henri Thévenin'), ('burial', 'Bartins Cemetery of Vichy'), ('birth', 'Vichy'), ('cname', 'France')]
# [('pname', 'Henry Becque'), ('burial', 'Père Lachaise Cemetery'), ('birth', 'Paris'), ('cname', 'France')]
# [('pname', 'Hermance Lesguillon'), ('burial', 'Père Lachaise Cemetery'), ('birth', 'Paris'), ('cname', 'France')]
# [('pname', 'Hégésippe Moreau'), ('burial', 'Montparnasse Cemetery'), ('birth', 'Paris'), ('cname', 'France')]
# [('pname', 'Jacques Baron'), ('burial', 'Père Lachaise Cemetery'), ('birth', 'Paris'), ('cname', 'France')]
# [('pname', 'Jacques Martel'), ('burial', 'Léré'), ('birth', 'Cher'), ('cname', 'France')]
# [('pname', 'Jacques Rigaut'), ('burial', 'Montmartre Cemetery'), ('birth', 'Paris'), ('cname', 'France')]
# [('pname', 'Jacques Spacagna'), ('burial', 'Crématorium-columbarium du Père-Lachaise'), ('birth', 'Paris'), ('cname', 'France')]
# [('pname', 'Jean Baptista von Schweitzer'), ('burial', 'Frankfurt Main Cemetery'), ('birth', 'Frankfurt am Main'), ('cname', 'Germany')]
# [('pname', 'Jean François Gail'), ('burial', 'Père Lachaise Cemetery'), ('birth', 'Paris'), ('cname', 'France')]
# [('pname', 'Jean-Baptiste Gaut'), ('burial', 'Saint-Pierre Cemetery'), ('birth', 'Aix-en-Provence'), ('cname', 'France')]
# [('pname', 'Jean-François Ducis'), ('burial', 'Cemetery of Saint-Louis, Versailles'), ('birth', 'Versailles'), ('cname', 'France')]
# [('pname', 'Jean-François de La Harpe'), ('burial', 'Père Lachaise Cemetery'), ('birth', 'Paris'), ('cname', 'France')]
# [('pname', 'Jean-Georges Farcy'), ('burial', 'Père Lachaise Cemetery'), ('birth', 'Paris'), ('cname', 'France')]
# [('pname', 'Jean-Pierre Giraudoux'), ('burial', 'Passy Cemetery'), ('birth', 'Paris'), ('cname', 'France')]
# [('pname', 'Johann Georg Daniel Arnold'), ('burial', 'Cimetière Saint-Gall de Strasbourg'), ('birth', 'Strasbourg'), ('cname', 'France')]
# [('pname', 'Johann Jakob Merlo'), ('burial', 'Melaten-Friedhof'), ('birth', 'Cologne'), ('cname', 'Germany')]
# [('pname', 'Joseph Roumanille'), ('burial', 'cemetery of Saint-Rémy-de-Provence'), ('birth', 'Saint-Rémy-de-Provence'), ('cname', 'France')]
# [('pname', 'Joseph Victor von Scheffel'), ('burial', 'Hauptfriedhof Karlsruhe'), ('birth', 'Karlsruhe'), ('cname', 'Germany')]
# [('pname', 'Josephin Soulary'), ('burial', 'Cemetery of Croix-Rousse'), ('birth', 'Lyon'), ('cname', 'France')]
# [('pname', "Jules Amédée Barbey d'Aurevilly"), ('burial', 'Saint-Sauveur-le-Vicomte'), ('birth', 'Saint-Sauveur-le-Vicomte'), ('cname', 'France')]
# [('pname', 'Jules Depaquit'), ('burial', 'Sedan'), ('birth', 'Sedan'), ('cname', 'France')]
# [('pname', 'Jules Jouy'), ('burial', 'Père Lachaise Cemetery'), ('birth', 'Paris'), ('cname', 'France')]
# [('pname', 'Jules Mousseron'), ('burial', 'Denain Communal Cemetery'), ('birth', 'Denain'), ('cname', 'France')]
# [('pname', 'Julien Gracq'), ('burial', 'Saint-Florent-le-Vieil'), ('birth', 'Saint-Florent-le-Vieil'), ('cname', 'France')]
# [('pname', 'Karl Joseph Simrock'), ('burial', 'Alter Friedhof'), ('birth', 'Bonn'), ('cname', 'Germany')]
# [('pname', 'Karl Krolow'), ('burial', 'Stadtfriedhof Engesohde'), ('birth', 'Hanover'), ('cname', 'Germany')]
# [('pname', 'Karl Vollmöller'), ('burial', 'Pragfriedhof Stuttgart'), ('birth', 'Stuttgart'), ('cname', 'Germany')]
# [('pname', 'Kurt Schwitters'), ('burial', 'Stadtfriedhof Engesohde'), ('birth', 'Hanover'), ('cname', 'Germany')]
# [('pname', 'Louis Becq de Fouquières'), ('burial', 'Père Lachaise Cemetery'), ('birth', 'Paris'), ('cname', 'France')]
# [('pname', 'Louis Janmot'), ('burial', 'Cimetière de Loyasse'), ('birth', 'Lyon'), ('cname', 'France')]
# [('pname', 'Louis Le Cardonnel'), ('burial', 'Valence'), ('birth', 'Valence'), ('cname', 'France')]
# [('pname', 'Louis-Sébastien Mercier'), ('burial', 'Père Lachaise Cemetery'), ('birth', 'Paris'), ('cname', 'France')]
# [('pname', 'Louise Lévêque de Vilmorin'), ('burial', 'Verrières-le-Buisson'), ('birth', 'Verrières-le-Buisson'), ('cname', 'France')]
# [('pname', 'Lucie Delarue-Mardrus'), ('burial', 'Cimetière Sainte-Catherine de Honfleur'), ('birth', 'Honfleur'), ('cname', 'France')]
# [('pname', 'Ludwig Rubiner'), ('burial', 'Friedhof Weißensee'), ('birth', 'Berlin'), ('cname', 'Germany')]
# [('pname', 'Léon Laurent-Pichat'), ('burial', 'Père Lachaise Cemetery'), ('birth', 'Paris'), ('cname', 'France')]
# [('pname', 'Léon Xanrof'), ('burial', 'Montmartre Cemetery'), ('birth', 'Paris'), ('cname', 'France')]
# [('pname', 'Léon Xanrof'), ('burial', 'Montmartre Cemetery'), ('birth', '18th arrondissement of Paris'), ('cname', 'France')]
# [('pname', 'Léopold Simons'), ('burial', 'Cimetière du Sud'), ('birth', 'Lille'), ('cname', 'France')]
# [('pname', 'Marcel Proust'), ('burial', 'Père Lachaise Cemetery'), ('birth', 'Paris'), ('cname', 'France')]
# [('pname', 'Marie Noël'), ('burial', 'Auxerre'), ('birth', 'Auxerre'), ('cname', 'France')]
# [('pname', 'Marie de Gournay'), ('burial', 'Church of St. Eustace'), ('birth', 'Paris'), ('cname', 'France')]
# [('pname', 'Martin Heidegger'), ('burial', 'Messkirch'), ('birth', 'Messkirch'), ('cname', 'Germany')]
# [('pname', 'Maurice Montégut'), ('burial', 'Montmartre Cemetery'), ('birth', 'Paris'), ('cname', 'France')]
# [('pname', 'Maurice Rostand'), ('burial', 'Passy Cemetery'), ('birth', 'Paris'), ('cname', 'France')]
# [('pname', 'Maxime Du Camp'), ('burial', 'Montmartre Cemetery'), ('birth', 'Paris'), ('cname', 'France')]
# [('pname', 'Meir ben Baruch'), ('burial', 'Jewish Cemetery'), ('birth', 'Worms'), ('cname', 'Germany')]
# [('pname', 'Mina Witkojc'), ('burial', 'Burg (Spreewald)'), ('birth', 'Burg (Spreewald)'), ('cname', 'Germany')]
# [('pname', 'Molière'), ('burial', 'Père Lachaise Cemetery'), ('birth', 'Paris'), ('cname', 'France')]
# [('pname', 'Nicolas Boileau-Despréaux'), ('burial', 'Abbey of Saint-Germain-des-Prés'), ('birth', 'Paris'), ('cname', 'France')]
# [('pname', 'Nicolas Brazier'), ('burial', 'Auteuil Cemetery'), ('birth', 'Paris'), ('cname', 'France')]
# [('pname', 'Nicole Louvier'), ('burial', 'Montparnasse Cemetery'), ('birth', 'Paris'), ('cname', 'France')]
# [('pname', 'Norbert Burger'), ('burial', 'Melaten-Friedhof'), ('birth', 'Cologne'), ('cname', 'Germany')]
# [('pname', 'Népomucène Lemercier'), ('burial', 'Père Lachaise Cemetery'), ('birth', 'Paris'), ('cname', 'France')]
# [('pname', 'Paul Arène'), ('burial', 'Sisteron'), ('birth', 'Sisteron'), ('cname', 'France')]
# [('pname', 'Paul Valéry'), ('burial', 'Cimetière Marin, Sète'), ('birth', 'Sète'), ('cname', 'France')]
# [('pname', 'Paul Verlet'), ('burial', 'Passy Cemetery'), ('birth', '16th arrondissement of Paris'), ('cname', 'France')]
# [('pname', 'Philippe Quinault'), ('burial', "Saint-Louis en l'Île"), ('birth', 'Paris'), ('cname', 'France')]
# [('pname', 'Pierre Beaumarchais'), ('burial', 'Père Lachaise Cemetery'), ('birth', 'Paris'), ('cname', 'France')]
# [('pname', 'Pierre Dupont'), ('burial', 'Cemetery of Croix-Rousse'), ('birth', 'Lyon'), ('cname', 'France')]
# [('pname', 'Pierre Laujon'), ('burial', 'Père Lachaise Cemetery'), ('birth', 'Paris'), ('cname', 'France')]
# [('pname', 'Pierre de Rozières'), ('burial', 'Mirecourt'), ('birth', 'Mirecourt'), ('cname', 'France')]
# [('pname', 'Pierre-Jean de Béranger'), ('burial', 'Père Lachaise Cemetery'), ('birth', 'Paris'), ('cname', 'France')]
# [('pname', 'Raphael Georges Lévy'), ('burial', 'Montparnasse Cemetery'), ('birth', 'Paris'), ('cname', 'France')]
# [('pname', 'René of Anjou'), ('burial', 'Angers Cathedral'), ('birth', 'Angers'), ('cname', 'France')]
# [('pname', 'Robert Desnos'), ('burial', 'Montparnasse Cemetery'), ('birth', 'Paris'), ('cname', 'France')]
# [('pname', 'Robert Sabatier'), ('burial', 'Montparnasse Cemetery'), ('birth', 'Paris'), ('cname', 'France')]
# [('pname', 'Roger Gilbert-Lecomte'), ('burial', "Cimetière de l'Est"), ('birth', 'Reims'), ('cname', 'France')]
# [('pname', 'Roger Toulouse'), ('burial', "Grand cimetière d'Orléans"), ('birth', 'Orléans'), ('cname', 'France')]
# [('pname', 'Roparz Hemon'), ('burial', 'Brest'), ('birth', 'Brest'), ('cname', 'France')]
# [('pname', 'Rosemonde Gérard'), ('burial', 'Passy Cemetery'), ('birth', 'Paris'), ('cname', 'France')]
# [('pname', 'Simonomis'), ('burial', 'Père Lachaise Cemetery'), ('birth', 'Paris'), ('cname', 'France')]
# [('pname', 'Sophie Hoechstetter'), ('burial', 'Galluskirche'), ('birth', 'Pappenheim'), ('cname', 'Germany')]
# [('pname', 'Sully Prudhomme'), ('burial', 'Père Lachaise Cemetery'), ('birth', 'Paris'), ('cname', 'France')]
# [('pname', 'Sutter-Laumann'), ('burial', 'Montmartre Cemetery'), ('birth', 'Paris'), ('cname', 'France')]
# [('pname', 'Théodore Aubanel'), ('burial', 'Cimetière Saint-Véran'), ('birth', 'Avignon'), ('cname', 'France')]
# [('pname', 'Thérèse Marie Augusta Élie de Beaumont'), ('burial', 'Montparnasse Cemetery'), ('birth', 'Paris'), ('cname', 'France')]
# [('pname', 'Tristan Corbière'), ('burial', 'Morlaix'), ('birth', 'Morlaix'), ('cname', 'France')]
# [('pname', 'Valery Larbaud'), ('burial', 'Bartins Cemetery of Vichy'), ('birth', 'Vichy'), ('cname', 'France')]
# [('pname', 'Valère Bernard'), ('burial', 'Saint Pierre Cemetery'), ('birth', 'Marseille'), ('cname', 'France')]
# [('pname', 'Virginie-Hélène Porgès'), ('burial', 'Père Lachaise Cemetery'), ('birth', 'Paris'), ('cname', 'France')]
# [('pname', 'Voltaire'), ('burial', 'Panthéon'), ('birth', 'Paris'), ('cname', 'France')]
# [('pname', 'Wilhelm Hauff'), ('burial', 'Hoppenlau Cemetery'), ('birth', 'Stuttgart'), ('cname', 'Germany')]
# [('pname', 'Wolfgang Borchert'), ('burial', 'Ohlsdorf Cemetery'), ('birth', 'Hamburg'), ('cname', 'Germany')]
# [('pname', 'Wolfgang Franz von Kobell'), ('burial', 'Alter Südfriedhof'), ('birth', 'Munich'), ('cname', 'Germany')]
# [('pname', 'Édouard Jaguer'), ('burial', 'Père Lachaise Cemetery'), ('birth', 'Paris'), ('cname', 'France')]
# [('pname', 'Édouard Pailleron'), ('burial', 'Père Lachaise Cemetery'), ('birth', 'Paris'), ('cname', 'France')]
# [('pname', 'Édouard René de Laboulaye'), ('burial', 'Père Lachaise Cemetery'), ('birth', 'Paris'), ('cname', 'France')]
# [('pname', 'Édouard Thierry'), ('burial', 'Père Lachaise Cemetery'), ('birth', 'Paris'), ('cname', 'France')]
# [('pname', 'Édouard Turquety'), ('burial', 'cimetière du Nord'), ('birth', 'Rennes'), ('cname', 'France')]
# [('pname', 'Émile Blémont'), ('burial', 'Père Lachaise Cemetery'), ('birth', 'Paris'), ('cname', 'France')]
# [('pname', 'Émile Guérin-Catelain'), ('burial', 'Père Lachaise Cemetery'), ('birth', 'Paris'), ('cname', 'France')]
# [('pname', 'Émile Hinzelin'), ('burial', 'Cimetière de Préville'), ('birth', 'Nancy'), ('cname', 'France')]
# [('pname', 'Émile Negrin'), ('burial', 'Cimetière du Grand Jas'), ('birth', 'Cannes'), ('cname', 'France')]
# [('pname', 'Étienne-Augustin De Wailly'), ('burial', 'Père Lachaise Cemetery'), ('birth', 'Paris'), ('cname', 'France')]
# [('pname', 'Éva Jouan'), ('burial', 'Belle Île'), ('birth', 'Belle Île'), ('cname', 'France')]
# 179

# %% [markdown]
# #### Comment
# In this way I have obtained the city in which a place of burial is located.
# The task is completed through the fact that a poet is retrieved only when the place of burial's city and the place of birth are the same.

# %%
#OLD QUERY: First tries of query that specialize the previous search but that is not usefull to fulfill in the correct way the task
#We can also retrieve the poets with same birth and burial place without looking at the city in which a place is located in France or Germany
queryString = """
SELECT ?wname ?birth ?burial ?oname ?cname
WHERE { 

# ?per wdt:P106 ?job ;
    # ?bi ?obj ;
    # ?bu ?obj .
# ?obj wdt:P17 ?c .

FILTER(?job = wd:Q49757).
FILTER(?bi = wdt:P19 && ?bu = wdt:P119).
FILTER(?c = wd:Q142 || ?c = wd:Q183).

# ?per <http://schema.org/name> ?wname.
# ?bi <http://schema.org/name> ?birth .
# ?bu <http://schema.org/name> ?burial .
# ?obj <http://schema.org/name> ?oname .
# ?c <http://schema.org/name> ?cname .
}
ORDER BY ASC (?wname)
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('wname', 'Alphonse Germain-Lacour'), ('birth', 'place of birth'), ('burial', 'place of burial'), ('oname', 'Moulins-sur-Orne'), ('cname', 'France')]
# [('wname', 'Boris Vian'), ('birth', 'place of birth'), ('burial', 'place of burial'), ('oname', "Ville-d'Avray"), ('cname', 'France')]
# [('wname', 'Charles Bécas'), ('birth', 'place of birth'), ('burial', 'place of burial'), ('oname', 'Ainhoa'), ('cname', 'France')]
# [('wname', 'Charles-Louis Philippe'), ('birth', 'place of birth'), ('burial', 'place of burial'), ('oname', 'Cérilly'), ('cname', 'France')]
# [('wname', 'Ernest Louis, Grand Duke of Hesse'), ('birth', 'place of birth'), ('burial', 'place of burial'), ('oname', 'Darmstadt'), ('cname', 'Germany')]
# [('wname', 'Erwan ar Moal'), ('birth', 'place of birth'), ('burial', 'place of burial'), ('oname', 'Coadout'), ('cname', 'France')]
# [('wname', 'Eugène Bizeau'), ('birth', 'place of birth'), ('burial', 'place of burial'), ('oname', 'Véretz'), ('cname', 'France')]
# [('wname', 'Gaston Bachelard'), ('birth', 'place of birth'), ('burial', 'place of burial'), ('oname', 'Bar-sur-Aube'), ('cname', 'France')]
# [('wname', 'Gisèle Barbotin'), ('birth', 'place of birth'), ('burial', 'place of burial'), ('oname', 'Argenton-sur-Creuse'), ('cname', 'France')]
# [('wname', "Jules Amédée Barbey d'Aurevilly"), ('birth', 'place of birth'), ('burial', 'place of burial'), ('oname', 'Saint-Sauveur-le-Vicomte'), ('cname', 'France')]
# [('wname', 'Jules Depaquit'), ('birth', 'place of birth'), ('burial', 'place of burial'), ('oname', 'Sedan'), ('cname', 'France')]
# [('wname', 'Julien Gracq'), ('birth', 'place of birth'), ('burial', 'place of burial'), ('oname', 'Saint-Florent-le-Vieil'), ('cname', 'France')]
# [('wname', 'Louis Le Cardonnel'), ('birth', 'place of birth'), ('burial', 'place of burial'), ('oname', 'Valence'), ('cname', 'France')]
# [('wname', 'Louise Lévêque de Vilmorin'), ('birth', 'place of birth'), ('burial', 'place of burial'), ('oname', 'Verrières-le-Buisson'), ('cname', 'France')]
# [('wname', 'Marie Noël'), ('birth', 'place of birth'), ('burial', 'place of burial'), ('oname', 'Auxerre'), ('cname', 'France')]
# [('wname', 'Martin Heidegger'), ('birth', 'place of birth'), ('burial', 'place of burial'), ('oname', 'Messkirch'), ('cname', 'Germany')]
# [('wname', 'Mina Witkojc'), ('birth', 'place of birth'), ('burial', 'place of burial'), ('oname', 'Burg (Spreewald)'), ('cname', 'Germany')]
# [('wname', 'Paul Arène'), ('birth', 'place of birth'), ('burial', 'place of burial'), ('oname', 'Sisteron'), ('cname', 'France')]
# [('wname', 'Pierre de Rozières'), ('birth', 'place of birth'), ('burial', 'place of burial'), ('oname', 'Mirecourt'), ('cname', 'France')]
# [('wname', 'Roparz Hemon'), ('birth', 'place of birth'), ('burial', 'place of burial'), ('oname', 'Brest'), ('cname', 'France')]
# [('wname', 'Tristan Corbière'), ('birth', 'place of birth'), ('burial', 'place of burial'), ('oname', 'Morlaix'), ('cname', 'France')]
# [('wname', 'Éva Jouan'), ('birth', 'place of birth'), ('burial', 'place of burial'), ('oname', 'Belle Île'), ('cname', 'France')]
# 22

# %% [markdown]
# ### Task 4.2
#
# 4.2 Which cities host the place of birth of the larger number of poets or writers across the two countries?

# %%
# Let's count the number of poets and writers born in each city of the two states, let's retrieve only the first 50 highest results to not overload the computation 
queryString = """
SELECT ?cname ?birth (COUNT(DISTINCT ?pname) AS ?num) WHERE { 

# ?per wdt:P106 ?job ; 
    # ?pobi ?bi .
# ?bi wdt:P17 ?c .

FILTER(?job = wd:Q36180 || ?job = wd:Q49757).
FILTER(?pobi = wdt:P19).
FILTER(?c = wd:Q142 || ?c = wd:Q183).

# ?per <http://schema.org/name> ?pname .
#?bu <http://schema.org/name> ?burial .
# ?bi <http://schema.org/name> ?birth .
# ?c <http://schema.org/name> ?cname .
}
GROUP BY ?cname ?birth
ORDER BY DESC (?num)
LIMIT 50
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('cname', 'France'), ('birth', 'Paris'), ('num', '2479')]
# [('cname', 'Germany'), ('birth', 'Berlin'), ('num', '1904')]
# [('cname', 'Germany'), ('birth', 'Hamburg'), ('num', '845')]
# [('cname', 'Germany'), ('birth', 'Munich'), ('num', '770')]
# [('cname', 'Germany'), ('birth', 'Leipzig'), ('num', '458')]
# [('cname', 'Germany'), ('birth', 'Cologne'), ('num', '434')]
# [('cname', 'Germany'), ('birth', 'Frankfurt am Main'), ('num', '420')]
# [('cname', 'Germany'), ('birth', 'Stuttgart'), ('num', '372')]
# [('cname', 'Germany'), ('birth', 'Dresden'), ('num', '365')]
# [('cname', 'Germany'), ('birth', 'Hanover'), ('num', '310')]
# [('cname', 'France'), ('birth', 'Lyon'), ('num', '255')]
# [('cname', 'France'), ('birth', 'Marseille'), ('num', '255')]
# [('cname', 'Germany'), ('birth', 'Düsseldorf'), ('num', '253')]
# [('cname', 'Germany'), ('birth', 'Nuremberg'), ('num', '231')]
# [('cname', 'France'), ('birth', 'Strasbourg'), ('num', '184')]
# [('cname', 'Germany'), ('birth', 'Bonn'), ('num', '177')]
# [('cname', 'Germany'), ('birth', 'Essen'), ('num', '176')]
# [('cname', 'France'), ('birth', 'Bordeaux'), ('num', '175')]
# [('cname', 'Germany'), ('birth', 'Magdeburg'), ('num', '162')]
# [('cname', 'Germany'), ('birth', 'Brunswick'), ('num', '155')]
# [('cname', 'Germany'), ('birth', 'Karlsruhe'), ('num', '154')]
# [('cname', 'Germany'), ('birth', 'Lübeck'), ('num', '145')]
# [('cname', 'Germany'), ('birth', 'Halle (Saale)'), ('num', '144')]
# [('cname', 'Germany'), ('birth', 'Mannheim'), ('num', '142')]
# [('cname', 'Germany'), ('birth', 'Kassel'), ('num', '141')]
# [('cname', 'Germany'), ('birth', 'Bremen'), ('num', '140')]
# [('cname', 'France'), ('birth', 'Toulouse'), ('num', '135')]
# [('cname', 'Germany'), ('birth', 'Kiel'), ('num', '127')]
# [('cname', 'Germany'), ('birth', 'Mainz'), ('num', '125')]
# [('cname', 'Germany'), ('birth', 'Freiburg im Breisgau'), ('num', '124')]
# [('cname', 'France'), ('birth', 'Rouen'), ('num', '122')]
# [('cname', 'Germany'), ('birth', 'Darmstadt'), ('num', '120')]
# [('cname', 'Germany'), ('birth', 'Wiesbaden'), ('num', '119')]
# [('cname', 'Germany'), ('birth', 'Heidelberg'), ('num', '119')]
# [('cname', 'Germany'), ('birth', 'Münster'), ('num', '119')]
# [('cname', 'France'), ('birth', 'Neuilly-sur-Seine'), ('num', '117')]
# [('cname', 'Germany'), ('birth', 'Dortmund'), ('num', '114')]
# [('cname', 'France'), ('birth', 'Nantes'), ('num', '113')]
# [('cname', 'Germany'), ('birth', 'Chemnitz'), ('num', '112')]
# [('cname', 'Germany'), ('birth', 'Aachen'), ('num', '112')]
# [('cname', 'Germany'), ('birth', 'Augsburg'), ('num', '109')]
# [('cname', 'France'), ('birth', 'France'), ('num', '103')]
# [('cname', 'Germany'), ('birth', 'Göttingen'), ('num', '99')]
# [('cname', 'France'), ('birth', 'Nîmes'), ('num', '99')]
# [('cname', 'Germany'), ('birth', 'Würzburg'), ('num', '98')]
# [('cname', 'Germany'), ('birth', 'Erfurt'), ('num', '98')]
# [('cname', 'Germany'), ('birth', 'Free Hanseatic City of Bremen'), ('num', '97')]
# [('cname', 'France'), ('birth', 'Boulogne-Billancourt'), ('num', '93')]
# [('cname', 'Germany'), ('birth', 'Rostock'), ('num', '93')]
# [('cname', 'France'), ('birth', 'Lille'), ('num', '92')]
# 50

# %% [markdown]
# ### Task 4.3
#
# 4.3 What are the top 3 cities in each country that you could visit? Based on what criteria?

# %%
#In task 2 we retrieved the properties related to the node "Paris" maybe the list of monument property (wdt:P1456) leads to find some usefull information  
# Let's try to search for the properties of the list of monuments node related to each city 
queryString = """
SELECT ?bname ?pname ?oname WHERE { 

# ?per wdt:P106 ?job ; 
    # ?pob ?b .
# ?b wdt:P17 ?c ;
    wdt:P1456 ?l.
# ?l ?p ?obj .

FILTER(?job = wd:Q36180 || ?job = wd:Q49757).
FILTER(?pob = wdt:P19).
FILTER(?c = wd:Q142).

# ?obj <http://schema.org/name> ?oname .
# ?b <http://schema.org/name> ?bname .
# ?p <http://schema.org/name> ?pname .
}
GROUP BY ?cname ?bname
ORDER BY DESC (?num)
LIMIT 50
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('bname', 'Payroux'), ('pname', 'instance of'), ('oname', 'Wikimedia list article')]
# [('bname', 'Distré'), ('pname', 'country'), ('oname', 'France')]
# [('bname', 'Distré'), ('pname', 'is a list of'), ('oname', 'Historical Monument')]
# [('bname', 'Clermont'), ('pname', 'country'), ('oname', 'France')]
# [('bname', 'Gruey-lès-Surance'), ('pname', 'is a list of'), ('oname', 'Historical Monument')]
# [('bname', 'Goudelin'), ('pname', 'instance of'), ('oname', 'Wikimedia list article')]
# [('bname', 'Le Coudray-Macouard'), ('pname', 'instance of'), ('oname', 'Wikimedia list article')]
# [('bname', 'Saint-Florent-sur-Cher'), ('pname', 'instance of'), ('oname', 'Wikimedia list article')]
# [('bname', 'Goudelin'), ('pname', 'country'), ('oname', 'France')]
# [('bname', 'Gondrecourt-le-Château'), ('pname', 'country'), ('oname', 'France')]
# [('bname', 'Thiers'), ('pname', 'instance of'), ('oname', 'Wikimedia list article')]
# [('bname', 'Louannec'), ('pname', 'country'), ('oname', 'France')]
# [('bname', 'Erquy'), ('pname', 'country'), ('oname', 'France')]
# [('bname', 'Mende'), ('pname', 'country'), ('oname', 'France')]
# [('bname', 'Munster'), ('pname', 'country'), ('oname', 'France')]
# [('bname', 'Bayeux'), ('pname', 'is a list of'), ('oname', 'Historical Monument')]
# [('bname', 'Erquy'), ('pname', 'is a list of'), ('oname', 'Historical Monument')]
# [('bname', 'Quimperlé'), ('pname', 'instance of'), ('oname', 'Wikimedia list article')]
# [('bname', 'Greux'), ('pname', 'country'), ('oname', 'France')]
# [('bname', 'Saint-Malo'), ('pname', 'instance of'), ('oname', 'Wikimedia list article')]
# [('bname', 'Saint-Malo'), ('pname', 'country'), ('oname', 'France')]
# [('bname', 'Lunéville'), ('pname', 'is a list of'), ('oname', 'Historical Monument')]
# [('bname', 'Saint-Dié-des-Vosges'), ('pname', 'category related to list'), ('oname', 'Category:Monuments historiques in Saint-Dié-des-Vosges')]
# [('bname', 'Ancerville'), ('pname', 'is a list of'), ('oname', 'Object as Historical Monument')]
# [('bname', 'Sainte-Marie-aux-Mines'), ('pname', 'instance of'), ('oname', 'Wikimedia list article')]
# [('bname', 'Ferrette'), ('pname', 'instance of'), ('oname', 'Wikimedia list article')]
# [('bname', 'Durmenach'), ('pname', 'instance of'), ('oname', 'Wikimedia list article')]
# [('bname', 'Hartmannswiller'), ('pname', 'instance of'), ('oname', 'Wikimedia list article')]
# [('bname', 'Salins-les-Bains'), ('pname', 'is a list of'), ('oname', 'Historical Monument')]
# [('bname', 'Bayonne'), ('pname', 'is a list of'), ('oname', 'Historical Monument')]
# [('bname', 'Vannes'), ('pname', 'category related to list'), ('oname', 'Category:Monuments historiques in Vannes')]
# [('bname', 'Bezons'), ('pname', 'is a list of'), ('oname', 'Historical Monument')]
# [('bname', 'Clermont-Ferrand'), ('pname', 'country'), ('oname', 'France')]
# [('bname', 'Gennevilliers'), ('pname', 'instance of'), ('oname', 'Wikimedia list article')]
# [('bname', 'Troyes'), ('pname', 'is a list of'), ('oname', 'Historical Monument')]
# [('bname', 'Belley'), ('pname', 'instance of'), ('oname', 'Wikimedia list article')]
# [('bname', 'Martinique'), ('pname', 'instance of'), ('oname', 'Wikimedia list article')]
# [('bname', 'Yvias'), ('pname', 'country'), ('oname', 'France')]
# [('bname', 'Belley'), ('pname', 'is a list of'), ('oname', 'Historical Monument')]
# [('bname', 'Châteauneuf-sur-Cher'), ('pname', 'instance of'), ('oname', 'Wikimedia list article')]
# [('bname', 'Vineuil-Saint-Firmin'), ('pname', 'country'), ('oname', 'France')]
# [('bname', 'Châteauneuf-sur-Cher'), ('pname', 'country'), ('oname', 'France')]
# [('bname', 'Mortcerf'), ('pname', 'country'), ('oname', 'France')]
# [('bname', 'Cambrai'), ('pname', 'instance of'), ('oname', 'Wikimedia list article')]
# [('bname', 'Vesoul'), ('pname', 'instance of'), ('oname', 'Wikimedia list article')]
# [('bname', 'Saint-Carreuc'), ('pname', 'instance of'), ('oname', 'Wikimedia list article')]
# [('bname', 'Châtillon-sur-Seine'), ('pname', 'country'), ('oname', 'France')]
# [('bname', 'Saint-Carreuc'), ('pname', 'country'), ('oname', 'France')]
# [('bname', 'Alençon'), ('pname', 'is a list of'), ('oname', 'Historical Monument')]
# [('bname', 'Dieppe'), ('pname', 'is a list of'), ('oname', 'Historical Monument')]
# 50

# %% [markdown]
# #### Coment
# No interesting properties found.
# Let's try with the "owner of" property (wdt:P1830), maybe can figure out something interesting

# %%
#Let's see the nodes connected to a city through the "owner of" property 
queryString = """
SELECT DISTINCT ?cname ?bname ?oname WHERE { 

# ?per wdt:P106 ?job ; 
    # ?pob ?b .
# ?b wdt:P17 ?c ;
    wdt:P1830 ?o .

FILTER(?job = wd:Q36180 || ?job = wd:Q49757).
FILTER(?pob = wdt:P19).
FILTER(?c = wd:Q142).

# ?per <http://schema.org/name> ?pname .
# ?b <http://schema.org/name> ?bname .
# ?c <http://schema.org/name> ?cname .
# ?o <http://schema.org/name> ?oname .
}
#GROUP BY ?cname ?bname
#ORDER BY DESC (?num)
LIMIT 50
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('cname', 'France'), ('bname', 'Le Tampon'), ('oname', 'Stade Klébert Picard')]
# [('cname', 'France'), ('bname', 'Biarritz'), ('oname', 'Parc des Sports Aguiléra')]
# [('cname', 'France'), ('bname', 'Ploemeur'), ('oname', 'Château de Soye')]
# [('cname', 'France'), ('bname', 'Yzeure'), ('oname', 'Stade de Bellevue')]
# [('cname', 'France'), ('bname', 'La Rochelle'), ('oname', 'Hôtel de Ville de La Rochelle')]
# [('cname', 'France'), ('bname', 'La Rochelle'), ('oname', 'Stade Marcel-Deflandre')]
# [('cname', 'France'), ('bname', 'Antibes'), ('oname', 'Jean Bunoz Sports Hall')]
# [('cname', 'France'), ('bname', 'Antibes'), ('oname', 'Château Grimaldi (Antibes)')]
# [('cname', 'France'), ('bname', 'Reims'), ('oname', 'Église Saint-André (Reims)')]
# [('cname', 'France'), ('bname', 'Aubervilliers'), ('oname', 'Church of Notre-Dame-des-Vertus, Aubervilliers')]
# [('cname', 'France'), ('bname', 'Salins-les-Bains'), ('oname', 'Fort Saint-André')]
# [('cname', 'France'), ('bname', 'Gaillac'), ('oname', "Château d'Hutaud")]
# [('cname', 'France'), ('bname', 'Saint-Ouen-sur-Seine'), ('oname', "Grande Nef de l'Île-des-Vannes")]
# [('cname', 'France'), ('bname', 'Saint-Ouen-sur-Seine'), ('oname', 'Church of Saint-Ouen-le-Vieux')]
# [('cname', 'France'), ('bname', 'Meuse'), ('oname', 'Sous-préfecture de Verdun')]
# [('cname', 'France'), ('bname', 'Clermont-Ferrand'), ('oname', 'Stade Gabriel Montpied')]
# [('cname', 'France'), ('bname', 'Clermont-Ferrand'), ('oname', 'fontaine de la Pyramide')]
# [('cname', 'France'), ('bname', 'Bayonne'), ('oname', 'Stade Jean Dauger')]
# [('cname', 'France'), ('bname', 'Vannes'), ('oname', 'Stade de la Rabine')]
# [('cname', 'France'), ('bname', 'Vannes'), ('oname', 'Lavoirs de la Garenne')]
# [('cname', 'France'), ('bname', 'Lens'), ('oname', 'Stade Bollaert-Delelis')]
# [('cname', 'France'), ('bname', 'Briançon'), ('oname', 'patinoire René Froger')]
# [('cname', 'France'), ('bname', 'Oyonnax'), ('oname', 'Stade Charles-Mathon')]
# [('cname', 'France'), ('bname', 'Autun'), ('oname', "Tour de l'Horloge")]
# [('cname', 'France'), ('bname', 'Autun'), ('oname', 'Café de la Bourse')]
# [('cname', 'France'), ('bname', 'Autun'), ('oname', 'Fontaine Saint-Lazare')]
# [('cname', 'France'), ('bname', 'Évreux'), ('oname', 'Fontaine monumentale')]
# [('cname', 'France'), ('bname', 'Bourgoin-Jallieu'), ('oname', 'Stade Pierre Rajon')]
# [('cname', 'France'), ('bname', 'Douai'), ('oname', 'Kinomap')]
# [('cname', 'France'), ('bname', 'Vesoul'), ('oname', 'Notre-Dame-de-la-Motte')]
# [('cname', 'France'), ('bname', 'Vesoul'), ('oname', 'Collège de Marteroy')]
# [('cname', 'France'), ('bname', 'Vesoul'), ('oname', 'Louis-Garret library')]
# [('cname', 'France'), ('bname', 'Guingamp'), ('oname', 'Anciennes Prisons (Guingamp)')]
# [('cname', 'France'), ('bname', 'Guingamp'), ('oname', 'Stade de Roudourou')]
# [('cname', 'France'), ('bname', 'Le Perthus'), ('oname', 'Trophy of Pompey')]
# [('cname', 'France'), ('bname', 'Nantes'), ('oname', 'Stade de la Beaujoire')]
# [('cname', 'France'), ('bname', 'Brest'), ('oname', 'Manoir de Keroual')]
# [('cname', 'France'), ('bname', 'Chartres'), ('oname', 'Cellier de Loëns')]
# [('cname', 'France'), ('bname', 'Chambéry'), ('oname', 'Théâtre Charles-Dullin')]
# [('cname', 'France'), ('bname', 'Bourg-en-Bresse'), ('oname', 'Stade Marcel-Verchère')]
# [('cname', 'France'), ('bname', 'Savoie'), ('oname', 'Gare routière de Chambéry')]
# [('cname', 'France'), ('bname', 'Pau'), ('oname', 'Stade du Hameau')]
# [('cname', 'France'), ('bname', 'Orne'), ('oname', 'Château des Nouettes')]
# [('cname', 'France'), ('bname', 'Isère'), ('oname', "Gare d'Aoste-Saint-Genix")]
# [('cname', 'France'), ('bname', 'Soissons'), ('oname', 'Saint-Léger Abbey in Soissons')]
# [('cname', 'France'), ('bname', 'Saint-Germain-en-Laye'), ('oname', 'Camp des Loges')]
# [('cname', 'France'), ('bname', 'Saint-Germain-en-Laye'), ('oname', 'Stade Municipal Georges Lefèvre')]
# [('cname', 'France'), ('bname', 'Béziers'), ('oname', 'Stade Raoul-Barrière')]
# [('cname', 'France'), ('bname', 'Sens'), ('oname', 'Musées de Sens')]
# [('cname', 'France'), ('bname', 'Sens'), ('oname', 'Hôtel de Vaudricourt')]
# 50

# %% [markdown]
# #### Comment
# The results seems like a list of monument, places to see or things to see in that city.
# So maybe, taking into account this result, the number of destination nodes for the "owner of" property could be a fair measure parameter of how much could be interesting that city.

# %%
#Let's try to print what Paris owns
queryString = """
SELECT ?oname WHERE { 

wd:Q90 wdt:P1830 ?o .

# ?o <http://schema.org/name> ?oname .
}
GROUP BY ?cname ?bname
ORDER BY DESC (?num)
LIMIT 400
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('oname', 'Arc de Triomphe')]
# [('oname', 'La Sainte Catherine')]
# [('oname', "Pavillon d'Armenonville")]
# [('oname', 'Eiffel Tower')]
# [('oname', 'Hôtel de Chalon-Luxembourg')]
# [('oname', 'Belleville funicular tramway')]
# [('oname', 'hôtel Dodun')]
# [('oname', 'La Famille')]
# [('oname', 'Parc des Princes')]
# [('oname', 'fontaine de Jarente')]
# [('oname', 'pyramid of bois de Vincennes')]
# [('oname', 'Stade Jean-Bouin')]
# [('oname', 'La Fraternité')]
# [('oname', 'Accor Arena')]
# [('oname', 'Jacob Wrestling with the Angel')]
# [('oname', 'Alexander II')]
# [('oname', 'Paris Bourse')]
# [('oname', 'The Sleepers')]
# [('oname', 'Grand Synagogue of Paris')]
# 19

# %%
#Let's count the nodes connected to a French city through "owner of" property
queryString = """
SELECT ?cname ?bname (COUNT(DISTINCT ?oname) AS ?num) WHERE { 

# ?per wdt:P106 ?job ; 
    # ?pob ?b .
# ?b wdt:P17 ?c ;
    wdt:P1830 ?o .

FILTER(?job = wd:Q36180 || ?job = wd:Q49757).
FILTER(?pob = wdt:P19).
FILTER(?c = wd:Q142).

# ?per <http://schema.org/name> ?pname .
# ?b <http://schema.org/name> ?bname .
# ?c <http://schema.org/name> ?cname .
# ?o <http://schema.org/name> ?oname .
}
GROUP BY ?cname ?bname
ORDER BY DESC (?num)
LIMIT 6
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('cname', 'France'), ('bname', 'Paris'), ('num', '19')]
# [('cname', 'France'), ('bname', 'Bordeaux'), ('num', '5')]
# [('cname', 'France'), ('bname', 'Toulouse'), ('num', '5')]
# [('cname', 'France'), ('bname', 'Le Mans'), ('num', '4')]
# [('cname', 'France'), ('bname', 'Sens'), ('num', '4')]
# [('cname', 'France'), ('bname', 'Rouen'), ('num', '4')]
# 6

# %%
#Let's list the first six French cities for number of poets or writers born in it   
queryString = """
SELECT ?cname ?bname (COUNT(DISTINCT ?pname) AS ?num) WHERE { 

# ?per wdt:P106 ?job ; 
    # ?pob ?b .
# ?b wdt:P17 ?c .

FILTER(?job = wd:Q36180 || ?job = wd:Q49757).
FILTER(?pob = wdt:P19).
FILTER(?c = wd:Q142).

# ?per <http://schema.org/name> ?pname .
# ?b <http://schema.org/name> ?bname .
# ?c <http://schema.org/name> ?cname .
}
GROUP BY ?cname ?bname
ORDER BY DESC (?num)
LIMIT 6
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('cname', 'France'), ('bname', 'Paris'), ('num', '2479')]
# [('cname', 'France'), ('bname', 'Lyon'), ('num', '255')]
# [('cname', 'France'), ('bname', 'Marseille'), ('num', '255')]
# [('cname', 'France'), ('bname', 'Strasbourg'), ('num', '184')]
# [('cname', 'France'), ('bname', 'Bordeaux'), ('num', '175')]
# [('cname', 'France'), ('bname', 'Toulouse'), ('num', '135')]
# 6

# %%
#Let's count the nodes connected to a German city through "owner of" property
queryString = """
SELECT ?cname ?bname (COUNT(DISTINCT ?oname) AS ?num) WHERE { 

# ?per wdt:P106 ?job ; 
    # ?pob ?b .
# ?b wdt:P17 ?c ;
    wdt:P1830 ?o .

FILTER(?job = wd:Q36180 || ?job = wd:Q49757).
FILTER(?pob = wdt:P19).
FILTER(?c = wd:Q183).

# ?per <http://schema.org/name> ?pname .
# ?b <http://schema.org/name> ?bname .
# ?c <http://schema.org/name> ?cname .
# ?o <http://schema.org/name> ?oname .
}
GROUP BY ?cname ?bname
ORDER BY DESC (?num)
LIMIT 6
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('cname', 'Germany'), ('bname', 'Berlin'), ('num', '19')]
# [('cname', 'Germany'), ('bname', 'Witten'), ('num', '12')]
# [('cname', 'Germany'), ('bname', 'Frankfurt am Main'), ('num', '8')]
# [('cname', 'Germany'), ('bname', 'Bad Honnef'), ('num', '5')]
# [('cname', 'Germany'), ('bname', 'Wolfsburg'), ('num', '4')]
# [('cname', 'Germany'), ('bname', 'Essen'), ('num', '4')]
# 6

# %%
#Let's list the first six German cities for number of poets or writers born in it   
queryString = """
SELECT ?cname ?bname (COUNT(DISTINCT ?pname) AS ?num) WHERE { 

# ?per wdt:P106 ?job ; 
    # ?pob ?b .
# ?b wdt:P17 ?c .

FILTER(?job = wd:Q36180 || ?job = wd:Q49757).
FILTER(?pob = wdt:P19).
FILTER(?c = wd:Q183).

# ?per <http://schema.org/name> ?pname .
# ?b <http://schema.org/name> ?bname .
# ?c <http://schema.org/name> ?cname .
}
GROUP BY ?cname ?bname
ORDER BY DESC (?num)
LIMIT 6
"""

print("Results")
run_query(queryString)
# Out:
# Results
# [('cname', 'Germany'), ('bname', 'Berlin'), ('num', '1904')]
# [('cname', 'Germany'), ('bname', 'Hamburg'), ('num', '845')]
# [('cname', 'Germany'), ('bname', 'Munich'), ('num', '770')]
# [('cname', 'Germany'), ('bname', 'Leipzig'), ('num', '458')]
# [('cname', 'Germany'), ('bname', 'Cologne'), ('num', '434')]
# [('cname', 'Germany'), ('bname', 'Frankfurt am Main'), ('num', '420')]
# 6

# %% [markdown]
# #### Comment
# Supposing that I'm going to visit a city mainly because I'm interested in poets and writers I'd like to choose a city in which I can see interesting places related to the poets and writers life but with also some general interesting places and things to see.
#
# For this purpose with the "owner of" queries I found the city with interesting general things and places to see, instead with the other two query I can know how many poet and writers are born in a city and so I suppose that I can find some nice things to do or places to see related to them.
#
# So as a result, mergeing the outputs of the two types of queries my suggestion for French cities are Paris, Bordeaux and Toulouse and for German cities I suggest Berlin, Frankfurt am Main, and one between Hamburg and Munich.
#
# I'm pretty sure that Paris doesn't have only 19 places or things to visit, and this stands also for all the other cities taken into account, so I made an approximation only to what is retrieved through "owner of" property, even because looking at all the incoming edges of a city could have been too onerous in terms of time, computation and so on. Due to this fact this is only a "coarse-grained" estimation.

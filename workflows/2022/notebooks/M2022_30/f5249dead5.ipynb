# %% [markdown]
# # General instructions
#
# The goal of the project is to materialize a set of **exploratory workloads** over a real-world, large-scale,  open-domain KG: [WikiData](https://www.wikidata.org/wiki/Wikidata:Main_Page)
#
# An exploratory workload  is composed by a set of queries, where each query is related to the information obtained previously.
#
# An exploratory workload starts with a usually vague, open ended question, and does not assume the person issuing the workload has a clear understanding of the data contained in the target database or its structure.
#
# Remeber that:
#
# 1. All the queries must run in the python notebook
# 2. You can use classes and properties only if you find them via a SPARQL query that must be present in the notebook
# 3. You do not delete useless queries. Keep everything that is synthatically valid
#
# ```
# ?p <http://schema.org/name> ?name .
# ```
#
#     is the BGP returning a human-readable name of a property or a class in Wikidata.

# %%
## SETUP used later

from SPARQLWrapper import SPARQLWrapper, JSON


prefixString = """
##-f5249dead5-##
PREFIX wd: <http://www.wikidata.org/entity/> 
PREFIX wdt: <http://www.wikidata.org/prop/direct/> 
PREFIX sc: <http://schema.org/>
"""

# select and construct queries
def run_query(queryString,verbose = True):
    to_run = prefixString + "\n" + queryString

    sparql = SPARQLWrapper("http://a256-gc1-03.srv.aau.dk:5820/sparql")
    sparql.setTimeout(300)
    sparql.setReturnFormat(JSON)
    sparql.setQuery(to_run)

    try :
        results = sparql.query()
        json_results = results.convert()
        if len(json_results['results']['bindings'])==0:
            print("Empty")
            return []
        array = []
        for bindings in json_results['results']['bindings']:
            app =  [ (var, value['value'])  for var, value in bindings.items() ] 
            if verbose:
                print( app)
            array.append(app)
        if verbose:
            print(len(array))
        return array

    except Exception as e :
        print("The operation failed", e)
    
# ASk queries
def run_ask_query(queryString):
    to_run = prefixString + "\n" + queryString

    sparql = SPARQLWrapper("http://a256-gc1-03.srv.aau.dk:5820/sparql")
    sparql.setTimeout(300)
    sparql.setReturnFormat(JSON)
    sparql.setQuery(to_run)

    try :
        return sparql.query().convert()

    except Exception as e :
        print("The operation failed", e)

# %% [markdown]
# # Movie Workflow Series ("Tv series HIMYM explorative search")
#
#
# Consider the following exploratory scenario:
#
#
# > we are interested in the TV series "How I met your mother" and we want to investigate the main aspects related to the actors and directors involved in the production, know the numerber of seasons and check what are the episodes which got the higher success/impact.
#
#
# ## Useful URIs for the current workflow
# The following are given:
#
# | IRI           | Description   | Role      |
# | -----------   | -----------   |-----------|
# | `wdt:P1647`   | subproperty   | predicate |
# | `wdt:P31`     | instance of   | predicate |
# | `wdt:P106`    | profession    | predicate |
# | `wdt:P279`    | subclass      | predicate |
# | `wdt:P4969`    | derivative work      | predicate |
# | `wd:Q147235` | How I met your mother        | node |
# | `wd:Q23831` | The Office (US)        | node |
#
#
#
# Also consider
#
# ```
# wd:Q23831 ?p ?obj .
# ```
#
# is the BGP to retrieve all **properties of The Office (US)**
#
# Please consider that when you return a resource, you should return the IRI and the label of the resource. In particular, when the task require you to identify a BGP the result set must always be a list of couples IRI - label.
#
# The workload should
#
# 1. Identify the BGP for tv series
#
# 2. Return the number of seasons and episodes per season of the tv series (the result set must be triples of season IRI, label and #episodes).
#
# 3. Get the number of episodes in which the cast members played a role. Who are the most present actors? (the result set must be a list of triples actor/actress IRI, label and #episodes)
#
# 4. Check who is the actor who acted in more films while working on "How I met your mother" (the result set must be a list of triples actor/actress IRI, label and #films).
#
# 5. Compare HIMYM with the tv series "The Office (US)" in terms of number of seasons, episods and cast members (the result set must be two elements -one for each tv series- of tv series IRI, label, #seasons, #episodes and #cast members).
#
# 6. Return how many of the actors who are members of the cast of the tv series have [Kavin Bacon number](https://en.wikipedia.org/wiki/Six_Degrees_of_Kevin_Bacon#:~:text=Kevin%20Bacon%20himself%20has%20a,Bacon%20number%20is%20N%2B1.) equal to 2 (the result set must be a list of couples actor/actress IRI and label).
#
# 7. Consider the actors who are members of the cast of HIMYM. Amongst the tv series which these actors acted return only those which received more than 2 awards (the result set must be triples of tv series IRI, label, #awards won).

# %% [markdown]
# ## Task 1
# Identify the BGP for tv series

# %%
# query example
#Q23831 the Office
queryString = """
SELECT DISTINCT ?p ?name
WHERE {
   # bind something
   wd:Q23831 ?p ?obj .
   # get the label
   # ?p sc:name ?name.
}
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# The operation failed timed out

# %% [markdown]
# Final query for this task

# %%
# query example
#Q23831 the Office
queryString = """
SELECT DISTINCT ?obj ?objName
WHERE {
   # bind something
   wd:Q23831 wdt:P31 ?obj .
   # get the label
   # ?obj sc:name ?objName.
}
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('obj', 'http://www.wikidata.org/entity/Q5398426'), ('objName', 'television series')]
# 1

# %% [markdown]
# ## Task 2
# Return the number of seasons and episodes per season of the tv series (the result set must be triples of season IRI, label and #episodes).

# %%
# Q147235	How I met your mother
queryString = """
SELECT DISTINCT ?p ?name ?obj ?objName 
WHERE {
   # bind something
   wd:Q147235 ?p ?obj .
   
   # get the label
   # ?p sc:name ?name
   optional{?obj sc:name ?objName.}
   filter regex(?objName, "season").
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('name', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q2438066'), ('objName', 'How I Met Your Mother, season 6')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('name', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q2715578'), ('objName', 'How I Met Your Mother, season 1')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('name', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q13567027'), ('objName', 'How I Met Your Mother, season 9')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('name', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q2567330'), ('objName', 'How I Met Your Mother, season 4')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('name', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q338715'), ('objName', 'How I Met Your Mother, season 8')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('name', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q582332'), ('objName', 'How I Met Your Mother, season 5')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('name', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q3468515'), ('objName', 'How I Met Your Mother, season 2')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('name', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q2555117'), ('objName', 'How I Met Your Mother, season 3')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('name', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q2472427'), ('objName', 'How I Met Your Mother, season 7')]
# 9

# %%
# Q147235	How I met your mother
queryString = """
SELECT DISTINCT ?p ?name ?obj ?objName 
WHERE {
   # bind something
   wd:Q147235 ?p ?obj .
  
   
   # get the label
   # ?p sc:name ?name
   optional{?obj sc:name ?objName.}
   filter regex(?objName, "season").
}
ORDER BY ASC (?objName)
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('name', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q2715578'), ('objName', 'How I Met Your Mother, season 1')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('name', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q3468515'), ('objName', 'How I Met Your Mother, season 2')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('name', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q2555117'), ('objName', 'How I Met Your Mother, season 3')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('name', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q2567330'), ('objName', 'How I Met Your Mother, season 4')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('name', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q582332'), ('objName', 'How I Met Your Mother, season 5')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('name', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q2438066'), ('objName', 'How I Met Your Mother, season 6')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('name', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q2472427'), ('objName', 'How I Met Your Mother, season 7')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('name', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q338715'), ('objName', 'How I Met Your Mother, season 8')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('name', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q13567027'), ('objName', 'How I Met Your Mother, season 9')]
# 9

# %%
# Q2567330 'How I Met Your Mother, season 4'
queryString = """
SELECT DISTINCT ?p ?name
WHERE {
   # bind something
   wd:Q2567330 ?p ?obj .
   # get the label
   # ?p sc:name ?name.
}
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P1113'), ('name', 'number of episodes')]
# [('p', 'http://www.wikidata.org/prop/direct/P1258'), ('name', 'Rotten Tomatoes ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1712'), ('name', 'Metacritic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P179'), ('name', 'part of the series')]
# [('p', 'http://www.wikidata.org/prop/direct/P2529'), ('name', 'ČSFD film ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2638'), ('name', 'TV.com ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2704'), ('name', 'EIDR content ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('name', 'instance of')]
# [('p', 'http://www.wikidata.org/prop/direct/P3302'), ('name', 'Open Media Database film ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P364'), ('name', 'original language of film or TV show')]
# [('p', 'http://www.wikidata.org/prop/direct/P437'), ('name', 'distribution format')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('name', 'has part')]
# [('p', 'http://www.wikidata.org/prop/direct/P580'), ('name', 'start time')]
# [('p', 'http://www.wikidata.org/prop/direct/P582'), ('name', 'end time')]
# [('p', 'http://www.wikidata.org/prop/direct/P646'), ('name', 'Freebase ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P750'), ('name', 'distributed by')]
# [('p', 'http://www.wikidata.org/prop/direct/P6381'), ('name', 'iTunes TV season ID')]
# 17

# %% [markdown]
# Final query for this task

# %%
# write your final query
# P1113 number of episodes
# Q147235	How I met your mother
queryString = """
SELECT DISTINCT ?p ?name ?obj ?objName ?numeberEpisode 
WHERE {
   # bind something
   wd:Q147235 ?p ?obj .
   # ?obj wdt:P1113 ?numeberEpisode.
   
   # get the label
   # ?p sc:name ?name
   optional{?obj sc:name ?objName.}
   filter regex(?objName, "season").
}
ORDER BY ASC (?objName)
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('name', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q2715578'), ('objName', 'How I Met Your Mother, season 1'), ('numeberEpisode', '22')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('name', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q3468515'), ('objName', 'How I Met Your Mother, season 2'), ('numeberEpisode', '22')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('name', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q2555117'), ('objName', 'How I Met Your Mother, season 3'), ('numeberEpisode', '20')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('name', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q2567330'), ('objName', 'How I Met Your Mother, season 4'), ('numeberEpisode', '24')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('name', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q582332'), ('objName', 'How I Met Your Mother, season 5'), ('numeberEpisode', '24')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('name', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q2438066'), ('objName', 'How I Met Your Mother, season 6'), ('numeberEpisode', '24')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('name', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q2472427'), ('objName', 'How I Met Your Mother, season 7'), ('numeberEpisode', '24')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('name', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q338715'), ('objName', 'How I Met Your Mother, season 8'), ('numeberEpisode', '24')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('name', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q13567027'), ('objName', 'How I Met Your Mother, season 9'), ('numeberEpisode', '24')]
# 9

# %% [markdown]
# ## Task 3
# Get the number of episodes in which the cast members played a role. Who are the most present actors? (the result set must be a list of triples actor/actress IRI, label and #episodes)

# %%
# write your queries
# Q147235	How I met your mother
queryString = """
SELECT DISTINCT ?p ?name ?obj ?objName 
WHERE {
   # bind something
   wd:Q147235 ?p ?obj .
  
   
   # get the label
   # ?p sc:name ?name
   optional{?obj sc:name ?objName.}
   filter regex(?name, "cast").
}
ORDER BY ASC (?objName)
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P161'), ('name', 'cast member'), ('obj', 'http://www.wikidata.org/entity/Q8349'), ('objName', '"Weird Al" Yankovic')]
# [('p', 'http://www.wikidata.org/prop/direct/P161'), ('name', 'cast member'), ('obj', 'http://www.wikidata.org/entity/Q24576840'), ('objName', 'Aaron Hendry')]
# [('p', 'http://www.wikidata.org/prop/direct/P161'), ('name', 'cast member'), ('obj', 'http://www.wikidata.org/entity/Q667979'), ('objName', 'Aaron Hill')]
# [('p', 'http://www.wikidata.org/prop/direct/P161'), ('name', 'cast member'), ('obj', 'http://www.wikidata.org/entity/Q2708237'), ('objName', 'Abby Elliott')]
# [('p', 'http://www.wikidata.org/prop/direct/P161'), ('name', 'cast member'), ('obj', 'http://www.wikidata.org/entity/Q50736659'), ('objName', 'Abhi Sinha')]
# [('p', 'http://www.wikidata.org/prop/direct/P161'), ('name', 'cast member'), ('obj', 'http://www.wikidata.org/entity/Q321131'), ('objName', 'Abigail Spencer')]
# [('p', 'http://www.wikidata.org/prop/direct/P161'), ('name', 'cast member'), ('obj', 'http://www.wikidata.org/entity/Q50736705'), ('objName', 'Adam Paul')]
# [('p', 'http://www.wikidata.org/prop/direct/P161'), ('name', 'cast member'), ('obj', 'http://www.wikidata.org/entity/Q151866'), ('objName', 'Adriana Lima')]
# [('p', 'http://www.wikidata.org/prop/direct/P161'), ('name', 'cast member'), ('obj', 'http://www.wikidata.org/entity/Q2827706'), ('objName', "Ahna O'Reilly")]
# [('p', 'http://www.wikidata.org/prop/direct/P161'), ('name', 'cast member'), ('obj', 'http://www.wikidata.org/entity/Q2827976'), ('objName', 'Ailsa Marshall')]
# [('p', 'http://www.wikidata.org/prop/direct/P161'), ('name', 'cast member'), ('obj', 'http://www.wikidata.org/entity/Q50385499'), ('objName', 'Aisha Kabia')]
# [('p', 'http://www.wikidata.org/prop/direct/P161'), ('name', 'cast member'), ('obj', 'http://www.wikidata.org/entity/Q277895'), ('objName', 'Alan Thicke')]
# [('p', 'http://www.wikidata.org/prop/direct/P161'), ('name', 'cast member'), ('obj', 'http://www.wikidata.org/entity/Q9600735'), ('objName', 'Alec Medlock')]
# [('p', 'http://www.wikidata.org/prop/direct/P161'), ('name', 'cast member'), ('obj', 'http://www.wikidata.org/entity/Q929985'), ('objName', 'Alex Trebek')]
# [('p', 'http://www.wikidata.org/prop/direct/P161'), ('name', 'cast member'), ('obj', 'http://www.wikidata.org/entity/Q366322'), ('objName', 'Alexis Denisof')]
# [('p', 'http://www.wikidata.org/prop/direct/P161'), ('name', 'cast member'), ('obj', 'http://www.wikidata.org/entity/Q199927'), ('objName', 'Alyson Hannigan')]
# [('p', 'http://www.wikidata.org/prop/direct/P161'), ('name', 'cast member'), ('obj', 'http://www.wikidata.org/entity/Q450496'), ('objName', 'Alyssa Shafer')]
# [('p', 'http://www.wikidata.org/prop/direct/P161'), ('name', 'cast member'), ('obj', 'http://www.wikidata.org/entity/Q50736838'), ('objName', 'Alyssa Smith')]
# [('p', 'http://www.wikidata.org/prop/direct/P161'), ('name', 'cast member'), ('obj', 'http://www.wikidata.org/entity/Q4739684'), ('objName', 'Amanda Loncar')]
# [('p', 'http://www.wikidata.org/prop/direct/P161'), ('name', 'cast member'), ('obj', 'http://www.wikidata.org/entity/Q131332'), ('objName', 'Amanda Peet')]
# 20

# %%
#P161  'cast member'
#Q131332 'Amanda Peet'
queryString = """
SELECT DISTINCT ?p ?name ?obj ?objName 
WHERE {
   # bind something
   wd:Q131332 ?p ?obj .
  
   
   # get the label
   # ?p sc:name ?name
   optional{?obj sc:name ?objName.}
   
}
ORDER BY ASC (?objName)
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P735'), ('name', 'given name'), ('obj', 'http://www.wikidata.org/entity/Q453722'), ('objName', 'Amanda')]
# [('p', 'http://www.wikidata.org/prop/direct/P140'), ('name', 'religion'), ('obj', 'http://www.wikidata.org/entity/Q5043'), ('objName', 'Christianity')]
# [('p', 'http://www.wikidata.org/prop/direct/P69'), ('name', 'educated at'), ('obj', 'http://www.wikidata.org/entity/Q49088'), ('objName', 'Columbia University')]
# [('p', 'http://www.wikidata.org/prop/direct/P26'), ('name', 'spouse'), ('obj', 'http://www.wikidata.org/entity/Q503997'), ('objName', 'David Benioff')]
# [('p', 'http://www.wikidata.org/prop/direct/P1412'), ('name', 'languages spoken, written or signed'), ('obj', 'http://www.wikidata.org/entity/Q1860'), ('objName', 'English')]
# [('p', 'http://www.wikidata.org/prop/direct/P69'), ('name', 'educated at'), ('obj', 'http://www.wikidata.org/entity/Q5504210'), ('objName', 'Friends Seminary')]
# [('p', 'http://www.wikidata.org/prop/direct/P140'), ('name', 'religion'), ('obj', 'http://www.wikidata.org/entity/Q9268'), ('objName', 'Judaism')]
# [('p', 'http://www.wikidata.org/prop/direct/P19'), ('name', 'place of birth'), ('obj', 'http://www.wikidata.org/entity/Q60'), ('objName', 'New York City')]
# [('p', 'http://www.wikidata.org/prop/direct/P1343'), ('name', 'described by source'), ('obj', 'http://www.wikidata.org/entity/Q67311526'), ('objName', 'Obalky knih.cz')]
# [('p', 'http://www.wikidata.org/prop/direct/P734'), ('name', 'family name'), ('obj', 'http://www.wikidata.org/entity/Q29048747'), ('objName', 'Peet')]
# [('p', 'http://www.wikidata.org/prop/direct/P25'), ('name', 'mother'), ('obj', 'http://www.wikidata.org/entity/Q22925648'), ('objName', 'Penny Peet')]
# [('p', 'http://www.wikidata.org/prop/direct/P27'), ('name', 'country of citizenship'), ('obj', 'http://www.wikidata.org/entity/Q30'), ('objName', 'United States of America')]
# [('p', 'http://www.wikidata.org/prop/direct/P1066'), ('name', 'student of'), ('obj', 'http://www.wikidata.org/entity/Q64260'), ('objName', 'Uta Hagen')]
# [('p', 'http://www.wikidata.org/prop/direct/P1340'), ('name', 'eye color'), ('obj', 'http://www.wikidata.org/entity/Q17122834'), ('objName', 'blue')]
# [('p', 'http://www.wikidata.org/prop/direct/P21'), ('name', 'sex or gender'), ('obj', 'http://www.wikidata.org/entity/Q6581072'), ('objName', 'female')]
# [('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation'), ('obj', 'http://www.wikidata.org/entity/Q10800557'), ('objName', 'film actor')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('name', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q5'), ('objName', 'human')]
# [('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation'), ('obj', 'http://www.wikidata.org/entity/Q214917'), ('objName', 'playwright')]
# [('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation'), ('obj', 'http://www.wikidata.org/entity/Q177220'), ('objName', 'singer')]
# [('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation'), ('obj', 'http://www.wikidata.org/entity/Q2259451'), ('objName', 'stage actor')]
# [('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation'), ('obj', 'http://www.wikidata.org/entity/Q10798782'), ('objName', 'television actor')]
# [('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation'), ('obj', 'http://www.wikidata.org/entity/Q578109'), ('objName', 'television producer')]
# [('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation'), ('obj', 'http://www.wikidata.org/entity/Q36180'), ('objName', 'writer')]
# [('p', 'http://www.wikidata.org/prop/direct/P1006'), ('name', 'Nationale Thesaurus voor Auteurs ID'), ('obj', '301251045')]
# [('p', 'http://www.wikidata.org/prop/direct/P1015'), ('name', 'NORAF ID'), ('obj', '4080487')]
# [('p', 'http://www.wikidata.org/prop/direct/P1207'), ('name', 'NUKAT ID'), ('obj', 'n2009158154')]
# [('p', 'http://www.wikidata.org/prop/direct/P1220'), ('name', 'Internet Broadway Database person ID'), ('obj', '389712')]
# [('p', 'http://www.wikidata.org/prop/direct/P1258'), ('name', 'Rotten Tomatoes ID'), ('obj', 'celebrity/amanda_peet')]
# [('p', 'http://www.wikidata.org/prop/direct/P1263'), ('name', 'NNDB people ID'), ('obj', '966/000031873')]
# [('p', 'http://www.wikidata.org/prop/direct/P1266'), ('name', 'AlloCiné person ID'), ('obj', '32764')]
# [('p', 'http://www.wikidata.org/prop/direct/P1273'), ('name', 'CANTIC ID'), ('obj', 'a10445444')]
# [('p', 'http://www.wikidata.org/prop/direct/P1417'), ('name', 'Encyclopædia Britannica Online ID'), ('obj', 'Amanda-Peet')]
# [('p', 'http://www.wikidata.org/prop/direct/P1649'), ('name', 'KMDb person ID'), ('obj', '00049033')]
# [('p', 'http://www.wikidata.org/prop/direct/P1695'), ('name', 'NLP ID (unique)'), ('obj', 'A20574782')]
# [('p', 'http://www.wikidata.org/prop/direct/P1712'), ('name', 'Metacritic ID'), ('obj', 'person/amanda-peet')]
# [('p', 'http://www.wikidata.org/prop/direct/P18'), ('name', 'image'), ('obj', 'http://commons.wikimedia.org/wiki/Special:FilePath/Amanda%20Peet%20%40%20TIFF%2001-2.jpg')]
# [('p', 'http://www.wikidata.org/prop/direct/P18'), ('name', 'image'), ('obj', 'http://commons.wikimedia.org/wiki/Special:FilePath/Amanda%20Peet%20September%202014%20%28cropped%29.jpg')]
# [('p', 'http://www.wikidata.org/prop/direct/P18'), ('name', 'image'), ('obj', 'http://commons.wikimedia.org/wiki/Special:FilePath/Amanda%20Peet%20at%20Light%20Up%20a%20Life.jpg')]
# [('p', 'http://www.wikidata.org/prop/direct/P2019'), ('name', 'AllMovie person ID'), ('obj', 'p215968')]
# [('p', 'http://www.wikidata.org/prop/direct/P2031'), ('name', 'work period (start)'), ('obj', '1995-01-01T00:00:00Z')]
# [('p', 'http://www.wikidata.org/prop/direct/P213'), ('name', 'ISNI'), ('obj', '0000 0001 1476 6187')]
# [('p', 'http://www.wikidata.org/prop/direct/P214'), ('name', 'VIAF ID'), ('obj', '85549417')]
# [('p', 'http://www.wikidata.org/prop/direct/P2168'), ('name', 'Swedish Film Database person ID'), ('obj', '237671')]
# [('p', 'http://www.wikidata.org/prop/direct/P227'), ('name', 'GND ID'), ('obj', '137325622')]
# [('p', 'http://www.wikidata.org/prop/direct/P2387'), ('name', 'Elonet person ID'), ('obj', '954145')]
# [('p', 'http://www.wikidata.org/prop/direct/P2435'), ('name', 'PORT person ID'), ('obj', '25570')]
# [('p', 'http://www.wikidata.org/prop/direct/P244'), ('name', 'Library of Congress authority ID'), ('obj', 'no2003027741')]
# [('p', 'http://www.wikidata.org/prop/direct/P2519'), ('name', 'Scope.dk person ID'), ('obj', '5799')]
# [('p', 'http://www.wikidata.org/prop/direct/P2604'), ('name', 'Kinopoisk person ID'), ('obj', '22153')]
# [('p', 'http://www.wikidata.org/prop/direct/P2605'), ('name', 'ČSFD person ID'), ('obj', '9755')]
# [('p', 'http://www.wikidata.org/prop/direct/P2626'), ('name', 'Danish National Filmography person ID'), ('obj', '148182')]
# [('p', 'http://www.wikidata.org/prop/direct/P2638'), ('name', 'TV.com ID'), ('obj', 'people/amanda-peet')]
# [('p', 'http://www.wikidata.org/prop/direct/P2639'), ('name', 'Filmportal ID'), ('obj', 'c10ae4da874641e8984e381a5fc1185e')]
# [('p', 'http://www.wikidata.org/prop/direct/P268'), ('name', 'Bibliothèque nationale de France ID'), ('obj', '140550437')]
# [('p', 'http://www.wikidata.org/prop/direct/P2688'), ('name', 'Box Office Mojo person ID'), ('obj', 'amandapeet')]
# [('p', 'http://www.wikidata.org/prop/direct/P269'), ('name', 'IdRef ID'), ('obj', '140324925')]
# [('p', 'http://www.wikidata.org/prop/direct/P3056'), ('name', 'TCM Movie Database person ID'), ('obj', '348995')]
# [('p', 'http://www.wikidata.org/prop/direct/P3142'), ('name', 'EDb person ID'), ('obj', 'n0000035')]
# [('p', 'http://www.wikidata.org/prop/direct/P3368'), ('name', 'Prabook ID'), ('obj', '181995')]
# [('p', 'http://www.wikidata.org/prop/direct/P3430'), ('name', 'SNAC ARK ID'), ('obj', 'w6kd2twk')]
# [('p', 'http://www.wikidata.org/prop/direct/P345'), ('name', 'IMDb ID'), ('obj', 'nm0001605')]
# [('p', 'http://www.wikidata.org/prop/direct/P373'), ('name', 'Commons category'), ('obj', 'Amanda Peet')]
# [('p', 'http://www.wikidata.org/prop/direct/P434'), ('name', 'MusicBrainz artist ID'), ('obj', '8ebb3500-3ddc-4a54-8adc-ff0dcd961773')]
# [('p', 'http://www.wikidata.org/prop/direct/P4985'), ('name', 'TMDb person ID'), ('obj', '2956')]
# [('p', 'http://www.wikidata.org/prop/direct/P5033'), ('name', 'Filmweb.pl person ID'), ('obj', '7803')]
# [('p', 'http://www.wikidata.org/prop/direct/P5534'), ('name', 'Open Media Database person ID'), ('obj', '2956')]
# [('p', 'http://www.wikidata.org/prop/direct/P5617'), ('name', 'Evene ID'), ('obj', 'amanda-peet-42203')]
# [('p', 'http://www.wikidata.org/prop/direct/P569'), ('name', 'date of birth'), ('obj', '1972-01-11T00:00:00Z')]
# [('p', 'http://www.wikidata.org/prop/direct/P5905'), ('name', 'Comic Vine ID'), ('obj', '4040-69397')]
# [('p', 'http://www.wikidata.org/prop/direct/P6255'), ('name', 'SinemaTürk person ID'), ('obj', '15668-amanda-peet')]
# [('p', 'http://www.wikidata.org/prop/direct/P646'), ('name', 'Freebase ID'), ('obj', '/m/03m8lq')]
# [('p', 'http://www.wikidata.org/prop/direct/P691'), ('name', 'NKCR AUT ID'), ('obj', 'xx0039793')]
# [('p', 'http://www.wikidata.org/prop/direct/P7214'), ('name', 'Allcinema person ID'), ('obj', '77881')]
# [('p', 'http://www.wikidata.org/prop/direct/P7293'), ('name', 'PLWABN ID'), ('obj', '9810568054405606')]
# [('p', 'http://www.wikidata.org/prop/direct/P7803'), ('name', 'Decine21 person ID'), ('obj', '5813')]
# [('p', 'http://www.wikidata.org/prop/direct/P7859'), ('name', 'WorldCat Identities ID'), ('obj', 'lccn-no2003027741')]
# [('p', 'http://www.wikidata.org/prop/direct/P7902'), ('name', 'Deutsche Biographie (GND) ID'), ('obj', '137325622')]
# [('p', 'http://www.wikidata.org/prop/direct/P8013'), ('name', 'Trakt.tv ID'), ('obj', 'people/amanda-peet')]
# [('p', 'http://www.wikidata.org/prop/direct/P8971'), ('name', 'Cinémathèque québécoise person ID'), ('obj', '153829')]
# [('p', 'http://www.wikidata.org/prop/direct/P9305'), ('name', 'Max Movie person ID'), ('obj', 'P000043142')]
# [('p', 'http://www.wikidata.org/prop/direct/P9404'), ('name', 'OFDb person ID'), ('obj', '901')]
# [('p', 'http://www.wikidata.org/prop/direct/P9463'), ('name', 'MovieMeter person ID'), ('obj', '2956')]
# [('p', 'http://www.wikidata.org/prop/direct/P950'), ('name', 'Biblioteca Nacional de España ID'), ('obj', 'XX1541125')]
# [('p', 'http://www.wikidata.org/prop/direct/P9662'), ('name', 'LdiF person ID'), ('obj', '142268')]
# [('p', 'http://www.wikidata.org/prop/direct/P9743'), ('name', 'Podchaser creator ID'), ('obj', '107Zzr2RC3')]
# 85

# %%
#Q13567027 'How I Met Your Mother, season 9'

queryString = """
SELECT DISTINCT ?p ?name ?obj ?objName 
WHERE {
   # bind something
   wd:Q13567027 ?p ?obj .
  
   
   # get the label
   # ?p sc:name ?name
   optional{?obj sc:name ?objName.}
   
   
}
ORDER BY ASC (?objName)
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P2684'), ('name', 'Kijkwijzer rating'), ('obj', 'http://www.wikidata.org/entity/Q23649982'), ('objName', '9')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('name', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q16746256'), ('objName', 'Bass Player Wanted')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('name', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q16746317'), ('objName', 'Bedtime Stories')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('name', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q16746145'), ('objName', 'Coming Back')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('name', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q16738646'), ('objName', 'Daisy')]
# [('p', 'http://www.wikidata.org/prop/direct/P364'), ('name', 'original language of film or TV show'), ('obj', 'http://www.wikidata.org/entity/Q1860'), ('objName', 'English')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('name', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q16745693'), ('objName', 'Gary Blauman')]
# [('p', 'http://www.wikidata.org/prop/direct/P179'), ('name', 'part of the series'), ('obj', 'http://www.wikidata.org/entity/Q147235'), ('objName', 'How I Met Your Mother')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('name', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q15983482'), ('objName', 'How Your Mother Met Me')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('name', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q16746204'), ('objName', 'Knight Vision')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('name', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q48986965'), ('objName', 'Last Forever, Part I')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('name', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q48986998'), ('objName', 'Last Forever, Part II')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('name', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q16746202'), ('objName', 'Last Time in New York')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('name', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q16746251'), ('objName', 'Mom and Dad')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('name', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q16746203'), ('objName', 'No Questions Asked')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('name', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q16746255'), ('objName', 'Platonish')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('name', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q15919313'), ('objName', 'Rally')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('name', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q15846040'), ('objName', 'Slapsgiving 3: Slappointment in Slapmarra')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('name', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q15983495'), ('objName', 'Sunrise')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('name', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q16746190'), ('objName', 'The Broken Code')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('name', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q16746366'), ('objName', 'The End of the Aisle')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('name', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q16746250'), ('objName', 'The Lighthouse')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('name', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q16746127'), ('objName', 'The Locket')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('name', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q16744027'), ('objName', 'The Poker Game')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('name', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q16746318'), ('objName', 'The Rehearsal Dinner')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('name', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q15846036'), ('objName', 'Unpause')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('name', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q16746365'), ('objName', 'Vesuvius')]
# [('p', 'http://www.wikidata.org/prop/direct/P437'), ('name', 'distribution format'), ('obj', 'http://www.wikidata.org/entity/Q54820071'), ('objName', 'digital download')]
# [('p', 'http://www.wikidata.org/prop/direct/P750'), ('name', 'distributed by'), ('obj', 'http://www.wikidata.org/entity/Q9589'), ('objName', 'iTunes')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('name', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q3464665'), ('objName', 'television series season')]
# [('p', 'http://www.wikidata.org/prop/direct/P437'), ('name', 'distribution format'), ('obj', 'http://www.wikidata.org/entity/Q723685'), ('objName', 'video on demand')]
# [('p', 'http://www.wikidata.org/prop/direct/P1113'), ('name', 'number of episodes'), ('obj', '24')]
# [('p', 'http://www.wikidata.org/prop/direct/P1258'), ('name', 'Rotten Tomatoes ID'), ('obj', 'tv/how_i_met_your_mother/s09')]
# [('p', 'http://www.wikidata.org/prop/direct/P1712'), ('name', 'Metacritic ID'), ('obj', 'tv/how-i-met-your-mother/season-9')]
# [('p', 'http://www.wikidata.org/prop/direct/P2529'), ('name', 'ČSFD film ID'), ('obj', '496074')]
# [('p', 'http://www.wikidata.org/prop/direct/P2638'), ('name', 'TV.com ID'), ('obj', 'shows/how-i-met-your-mother/season-9')]
# [('p', 'http://www.wikidata.org/prop/direct/P2704'), ('name', 'EIDR content ID'), ('obj', '10.5240/5A62-0A5D-6312-007B-0505-0')]
# [('p', 'http://www.wikidata.org/prop/direct/P3302'), ('name', 'Open Media Database film ID'), ('obj', '77907')]
# [('p', 'http://www.wikidata.org/prop/direct/P580'), ('name', 'start time'), ('obj', '2013-09-23T00:00:00Z')]
# [('p', 'http://www.wikidata.org/prop/direct/P582'), ('name', 'end time'), ('obj', '2014-03-31T00:00:00Z')]
# [('p', 'http://www.wikidata.org/prop/direct/P646'), ('name', 'Freebase ID'), ('obj', '/m/0v_xks9')]
# [('p', 'http://www.wikidata.org/prop/direct/P856'), ('name', 'official website'), ('obj', 'http://www.cbs.com/primetime/how_i_met_your_mother/')]
# [('p', 'http://www.wikidata.org/prop/direct/P6381'), ('name', 'iTunes TV season ID'), ('obj', '686812133')]
# 43

# %%
# Q16746256  'Bass Player Wanted'
queryString = """
SELECT DISTINCT ?p ?name ?obj ?objName 
WHERE {
   
   wd:Q16746256 ?p ?obj .
  
   # get the label
   # ?p sc:name ?name
   optional{?obj sc:name ?objName.}
   
   
}
ORDER BY ASC (?objName)
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P364'), ('name', 'original language of film or TV show'), ('obj', 'http://www.wikidata.org/entity/Q1860'), ('objName', 'English')]
# [('p', 'http://www.wikidata.org/prop/direct/P179'), ('name', 'part of the series'), ('obj', 'http://www.wikidata.org/entity/Q147235'), ('objName', 'How I Met Your Mother')]
# [('p', 'http://www.wikidata.org/prop/direct/P4908'), ('name', 'season'), ('obj', 'http://www.wikidata.org/entity/Q13567027'), ('objName', 'How I Met Your Mother, season 9')]
# [('p', 'http://www.wikidata.org/prop/direct/P57'), ('name', 'director'), ('obj', 'http://www.wikidata.org/entity/Q460221'), ('objName', 'Pamela Fryman')]
# [('p', 'http://www.wikidata.org/prop/direct/P156'), ('name', 'followed by'), ('obj', 'http://www.wikidata.org/entity/Q15846040'), ('objName', 'Slapsgiving 3: Slappointment in Slapmarra')]
# [('p', 'http://www.wikidata.org/prop/direct/P155'), ('name', 'follows'), ('obj', 'http://www.wikidata.org/entity/Q16746318'), ('objName', 'The Rehearsal Dinner')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('name', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q21191270'), ('objName', 'television series episode')]
# [('p', 'http://www.wikidata.org/prop/direct/P1258'), ('name', 'Rotten Tomatoes ID'), ('obj', 'tv/how_i_met_your_mother/s09/e13')]
# [('p', 'http://www.wikidata.org/prop/direct/P1476'), ('name', 'title'), ('obj', 'Bass Player Wanted')]
# [('p', 'http://www.wikidata.org/prop/direct/P1562'), ('name', 'AllMovie title ID'), ('obj', 'v609362')]
# [('p', 'http://www.wikidata.org/prop/direct/P2529'), ('name', 'ČSFD film ID'), ('obj', '496087')]
# [('p', 'http://www.wikidata.org/prop/direct/P2638'), ('name', 'TV.com ID'), ('obj', 'shows/how-i-met-your-mother/bass-player-wanted-2991994')]
# [('p', 'http://www.wikidata.org/prop/direct/P2704'), ('name', 'EIDR content ID'), ('obj', '10.5240/422D-1287-076E-8909-80ED-I')]
# [('p', 'http://www.wikidata.org/prop/direct/P3212'), ('name', 'ISAN'), ('obj', '0000-0002-2949-00B2-M-0000-0000-8')]
# [('p', 'http://www.wikidata.org/prop/direct/P3302'), ('name', 'Open Media Database film ID'), ('obj', '77920')]
# [('p', 'http://www.wikidata.org/prop/direct/P345'), ('name', 'IMDb ID'), ('obj', 'tt3382270')]
# [('p', 'http://www.wikidata.org/prop/direct/P4665'), ('name', 'CineMagia title ID'), ('obj', '695205')]
# [('p', 'http://www.wikidata.org/prop/direct/P577'), ('name', 'publication date'), ('obj', '2013-12-16T00:00:00Z')]
# [('p', 'http://www.wikidata.org/prop/direct/P646'), ('name', 'Freebase ID'), ('obj', '/m/0xn3hvr')]
# 19

# %%
# Q21191270  'television series episode' 
#P161 'cast member'
queryString = """
SELECT DISTINCT ?p ?name ?obj ?objName 
WHERE {
   
   wd:Q21191270 ?p ?obj .
  
   # get the label
   # ?p sc:name ?name
   optional{?obj sc:name ?objName.}
   
   
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('name', 'properties for this type'), ('obj', 'http://www.wikidata.org/entity/P31'), ('objName', 'instance of')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('name', 'subclass of'), ('obj', 'http://www.wikidata.org/entity/Q15416'), ('objName', 'television program')]
# [('p', 'http://www.wikidata.org/prop/direct/P1889'), ('name', 'different from'), ('obj', 'http://www.wikidata.org/entity/Q1261214'), ('objName', 'television special')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('name', 'properties for this type'), ('obj', 'http://www.wikidata.org/entity/P1476'), ('objName', 'title')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('name', 'subclass of'), ('obj', 'http://www.wikidata.org/entity/Q1983062'), ('objName', 'episode')]
# [('p', 'http://www.wikidata.org/prop/direct/P1889'), ('name', 'different from'), ('obj', 'http://www.wikidata.org/entity/Q1983062'), ('objName', 'episode')]
# [('p', 'http://www.wikidata.org/prop/direct/P1889'), ('name', 'different from'), ('obj', 'http://www.wikidata.org/entity/Q21664088'), ('objName', 'two-part episode')]
# [('p', 'http://www.wikidata.org/prop/direct/P361'), ('name', 'part of'), ('obj', 'http://www.wikidata.org/entity/Q5398426'), ('objName', 'television series')]
# [('p', 'http://www.wikidata.org/prop/direct/P361'), ('name', 'part of'), ('obj', 'http://www.wikidata.org/entity/Q3464665'), ('objName', 'television series season')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('name', 'properties for this type'), ('obj', 'http://www.wikidata.org/entity/P577'), ('objName', 'publication date')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('name', 'subclass of'), ('obj', 'http://www.wikidata.org/entity/Q2431196'), ('objName', 'audiovisual work')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('name', 'properties for this type'), ('obj', 'http://www.wikidata.org/entity/P179'), ('objName', 'part of the series')]
# [('p', 'http://www.wikidata.org/prop/direct/P6104'), ('name', 'maintained by WikiProject'), ('obj', 'http://www.wikidata.org/entity/Q8485793'), ('objName', 'WikiProject Film')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('name', 'properties for this type'), ('obj', 'http://www.wikidata.org/entity/P161'), ('objName', 'cast member')]
# [('p', 'http://www.wikidata.org/prop/direct/P1889'), ('name', 'different from'), ('obj', 'http://www.wikidata.org/entity/Q29555881'), ('objName', 'segment of a television episode')]
# [('p', 'http://www.wikidata.org/prop/direct/P910'), ('name', "topic's main category"), ('obj', 'http://www.wikidata.org/entity/Q7453224'), ('objName', 'Category:Television episodes')]
# [('p', 'http://www.wikidata.org/prop/direct/P1424'), ('name', "topic's main template"), ('obj', 'http://www.wikidata.org/entity/Q18606012'), ('objName', 'Template:The Simpsons episodes')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('name', 'properties for this type'), ('obj', 'http://www.wikidata.org/entity/P2364'), ('objName', 'production code')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('name', 'properties for this type'), ('obj', 'http://www.wikidata.org/entity/P4908'), ('objName', 'season')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('name', 'properties for this type'), ('obj', 'http://www.wikidata.org/entity/P57'), ('objName', 'director')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('name', 'properties for this type'), ('obj', 'http://www.wikidata.org/entity/P58'), ('objName', 'screenwriter')]
# [('p', 'http://www.wikidata.org/prop/direct/P1889'), ('name', 'different from'), ('obj', 'http://www.wikidata.org/entity/Q106942341'), ('objName', 'talk show episode')]
# [('p', 'http://www.wikidata.org/prop/direct/P1889'), ('name', 'different from'), ('obj', 'http://www.wikidata.org/entity/Q1464125'), ('objName', 'webisode')]
# [('p', 'http://www.wikidata.org/prop/direct/P1552'), ('name', 'has quality'), ('obj', 'http://www.wikidata.org/entity/Q39239591'), ('objName', 'number of episodes at the end of the current season or of the last season aired')]
# [('p', 'http://www.wikidata.org/prop/direct/P1552'), ('name', 'has quality'), ('obj', 'http://www.wikidata.org/entity/Q39242248'), ('objName', 'number of episodes aired')]
# [('p', 'http://www.wikidata.org/prop/direct/P1552'), ('name', 'has quality'), ('obj', 'http://www.wikidata.org/entity/Q39242358'), ('objName', 'number of episodes produced')]
# [('p', 'http://www.wikidata.org/prop/direct/P1889'), ('name', 'different from'), ('obj', 'http://www.wikidata.org/entity/Q50062923'), ('objName', 'three-part episode')]
# [('p', 'http://www.wikidata.org/prop/direct/P1889'), ('name', 'different from'), ('obj', 'http://www.wikidata.org/entity/Q50914552'), ('objName', 'four-part episode')]
# [('p', 'http://www.wikidata.org/prop/direct/P1552'), ('name', 'has quality'), ('obj', 'http://www.wikidata.org/entity/Q59180636'), ('objName', 'episode title')]
# [('p', 'http://www.wikidata.org/prop/direct/P1424'), ('name', "topic's main template"), ('obj', 'http://www.wikidata.org/entity/Q7880352'), ('objName', 'Template:Infobox television episode')]
# [('p', 'http://www.wikidata.org/prop/direct/P1889'), ('name', 'different from'), ('obj', 'http://www.wikidata.org/entity/Q99079902'), ('objName', 'five-part episode')]
# [('p', 'http://www.wikidata.org/prop/direct/P1424'), ('name', "topic's main template"), ('obj', 'http://www.wikidata.org/entity/Q25989841')]
# [('p', 'http://www.wikidata.org/prop/direct/P1709'), ('name', 'equivalent class'), ('obj', 'https://schema.org/TVEpisode')]
# [('p', 'http://www.wikidata.org/prop/direct/P2581'), ('name', 'BabelNet ID'), ('obj', '05041170n')]
# [('p', 'http://www.wikidata.org/prop/direct/P3417'), ('name', 'Quora topic ID'), ('obj', 'Tv-Series-Episode')]
# [('p', 'http://www.wikidata.org/prop/direct/P646'), ('name', 'Freebase ID'), ('obj', '/m/01xrzlb')]
# [('p', 'http://www.wikidata.org/prop/direct/P8408'), ('name', 'KBpedia ID'), ('obj', 'TelevisionEpisode')]
# 37

# %%
# P161 cast member
# Q16746256  'Bass Player Wanted'
queryString = """
SELECT DISTINCT ?p ?name ?obj ?objName 
WHERE {
   
   wd:Q16746256 wdt:P161 ?obj .
  
   # get the label
   
   optional{?obj sc:name ?objName.}
   
   
}
ORDER BY ASC (?objName)
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# Empty

# %%
#Q13567027 'How I Met Your Mother, season 9'
# P527 has part
 
## Q147235	How I met your mother

queryString = """ 
SELECT DISTINCT  ?seasonName ?epName ?castName
WHERE {
   # bind something
   wd:Q147235 wdt:P527 ?season.
   
   # ?season wdt:P527 ?ep. # trovo gli episodi della serie
   
   # ?ep wdt:P161 ?cast.
       
  
   
   # get the label
   #?people sc:name ?peopleName.
   # ?ep sc:name ?epName.
   # ?cast sc:name ?castName.
   # ?season sc:name ?seasonName.
   
   
}
ORDER BY ASC (?seasonName )
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('seasonName', 'How I Met Your Mother, season 1'), ('epName', 'Drumroll, Please'), ('castName', 'Virginia Williams')]
# [('seasonName', 'How I Met Your Mother, season 1'), ('epName', 'The Wedding'), ('castName', 'Virginia Williams')]
# [('seasonName', 'How I Met Your Mother, season 1'), ('epName', 'Nothing Good Happens After 2 A.M.'), ('castName', 'Cobie Smulders')]
# [('seasonName', 'How I Met Your Mother, season 1'), ('epName', 'Okay Awesome'), ('castName', 'Cobie Smulders')]
# [('seasonName', 'How I Met Your Mother, season 1'), ('epName', 'Return of the Shirt'), ('castName', 'Cobie Smulders')]
# [('seasonName', 'How I Met Your Mother, season 1'), ('epName', 'Pilot'), ('castName', 'Cobie Smulders')]
# [('seasonName', 'How I Met Your Mother, season 1'), ('epName', 'Purple Giraffe'), ('castName', 'Cobie Smulders')]
# [('seasonName', 'How I Met Your Mother, season 1'), ('epName', 'Sweet Taste of Liberty'), ('castName', 'Cobie Smulders')]
# [('seasonName', 'How I Met Your Mother, season 1'), ('epName', 'Game Night'), ('castName', 'Cobie Smulders')]
# [('seasonName', 'How I Met Your Mother, season 1'), ('epName', 'Drumroll, Please'), ('castName', 'Cobie Smulders')]
# [('seasonName', 'How I Met Your Mother, season 1'), ('epName', 'Life Among the Gorillas'), ('castName', 'Cobie Smulders')]
# [('seasonName', 'How I Met Your Mother, season 1'), ('epName', 'Cupcake'), ('castName', 'Cobie Smulders')]
# [('seasonName', 'How I Met Your Mother, season 1'), ('epName', 'The Wedding'), ('castName', 'Cobie Smulders')]
# [('seasonName', 'How I Met Your Mother, season 1'), ('epName', 'Belly Full of Turkey'), ('castName', 'Cobie Smulders')]
# [('seasonName', 'How I Met Your Mother, season 1'), ('epName', 'Come On'), ('castName', 'Cobie Smulders')]
# [('seasonName', 'How I Met Your Mother, season 1'), ('epName', 'Mary the Paralegal'), ('castName', 'Cobie Smulders')]
# [('seasonName', 'How I Met Your Mother, season 1'), ('epName', 'Milk'), ('castName', 'Cobie Smulders')]
# [('seasonName', 'How I Met Your Mother, season 1'), ('epName', 'The Duel'), ('castName', 'Cobie Smulders')]
# [('seasonName', 'How I Met Your Mother, season 1'), ('epName', 'The Limo'), ('castName', 'Cobie Smulders')]
# [('seasonName', 'How I Met Your Mother, season 1'), ('epName', 'The Pineapple Incident'), ('castName', 'Cobie Smulders')]
# [('seasonName', 'How I Met Your Mother, season 1'), ('epName', 'Zip, Zip, Zip'), ('castName', 'Cobie Smulders')]
# [('seasonName', 'How I Met Your Mother, season 1'), ('epName', 'Best Prom Ever'), ('castName', 'Cobie Smulders')]
# [('seasonName', 'How I Met Your Mother, season 1'), ('epName', 'Matchmaker'), ('castName', 'Cobie Smulders')]
# [('seasonName', 'How I Met Your Mother, season 1'), ('epName', 'Slutty Pumpkin'), ('castName', 'Cobie Smulders')]
# [('seasonName', 'How I Met Your Mother, season 1'), ('epName', 'Nothing Good Happens After 2 A.M.'), ('castName', 'Ashley Williams')]
# [('seasonName', 'How I Met Your Mother, season 1'), ('epName', 'Game Night'), ('castName', 'Ashley Williams')]
# [('seasonName', 'How I Met Your Mother, season 1'), ('epName', 'Drumroll, Please'), ('castName', 'Ashley Williams')]
# [('seasonName', 'How I Met Your Mother, season 1'), ('epName', 'Cupcake'), ('castName', 'Ashley Williams')]
# [('seasonName', 'How I Met Your Mother, season 1'), ('epName', 'The Wedding'), ('castName', 'Ashley Williams')]
# [('seasonName', 'How I Met Your Mother, season 1'), ('epName', 'Zip, Zip, Zip'), ('castName', 'Ashley Williams')]
# [('seasonName', 'How I Met Your Mother, season 1'), ('epName', 'Belly Full of Turkey'), ('castName', 'Elizabeth Bogush')]
# [('seasonName', 'How I Met Your Mother, season 1'), ('epName', 'Okay Awesome'), ('castName', 'Samm Levine')]
# [('seasonName', 'How I Met Your Mother, season 1'), ('epName', 'Okay Awesome'), ('castName', 'Jayma Mays')]
# [('seasonName', 'How I Met Your Mother, season 1'), ('epName', 'Nothing Good Happens After 2 A.M.'), ('castName', 'George Cheung')]
# [('seasonName', 'How I Met Your Mother, season 1'), ('epName', 'Belly Full of Turkey'), ('castName', 'Bill Fagerbakke')]
# [('seasonName', 'How I Met Your Mother, season 1'), ('epName', 'Nothing Good Happens After 2 A.M.'), ('castName', 'Alyssa Shafer')]
# [('seasonName', 'How I Met Your Mother, season 1'), ('epName', 'The Limo'), ('castName', 'Kathleen Rose Perkins')]
# [('seasonName', 'How I Met Your Mother, season 1'), ('epName', 'Come On'), ('castName', 'Amy Acker')]
# [('seasonName', 'How I Met Your Mother, season 1'), ('epName', 'Nothing Good Happens After 2 A.M.'), ('castName', 'Neil Patrick Harris')]
# [('seasonName', 'How I Met Your Mother, season 1'), ('epName', 'Okay Awesome'), ('castName', 'Neil Patrick Harris')]
# [('seasonName', 'How I Met Your Mother, season 1'), ('epName', 'Return of the Shirt'), ('castName', 'Neil Patrick Harris')]
# [('seasonName', 'How I Met Your Mother, season 1'), ('epName', 'Pilot'), ('castName', 'Neil Patrick Harris')]
# [('seasonName', 'How I Met Your Mother, season 1'), ('epName', 'Purple Giraffe'), ('castName', 'Neil Patrick Harris')]
# [('seasonName', 'How I Met Your Mother, season 1'), ('epName', 'Sweet Taste of Liberty'), ('castName', 'Neil Patrick Harris')]
# [('seasonName', 'How I Met Your Mother, season 1'), ('epName', 'Game Night'), ('castName', 'Neil Patrick Harris')]
# [('seasonName', 'How I Met Your Mother, season 1'), ('epName', 'Drumroll, Please'), ('castName', 'Neil Patrick Harris')]
# [('seasonName', 'How I Met Your Mother, season 1'), ('epName', 'Life Among the Gorillas'), ('castName', 'Neil Patrick Harris')]
# [('seasonName', 'How I Met Your Mother, season 1'), ('epName', 'Cupcake'), ('castName', 'Neil Patrick Harris')]
# [('seasonName', 'How I Met Your Mother, season 1'), ('epName', 'The Wedding'), ('castName', 'Neil Patrick Harris')]
# [('seasonName', 'How I Met Your Mother, season 1'), ('epName', 'Belly Full of Turkey'), ('castName', 'Neil Patrick Harris')]
# [('seasonName', 'How I Met Your Mother, season 1'), ('epName', 'Come On'), ('castName', 'Neil Patrick Harris')]
# [('seasonName', 'How I Met Your Mother, season 1'), ('epName', 'Mary the Paralegal'), ('castName', 'Neil Patrick Harris')]
# [('seasonName', 'How I Met Your Mother, season 1'), ('epName', 'Milk'), ('castName', 'Neil Patrick Harris')]
# [('seasonName', 'How I Met Your Mother, season 1'), ('epName', 'The Duel'), ('castName', 'Neil Patrick Harris')]
# [('seasonName', 'How I Met Your Mother, season 1'), ('epName', 'The Limo'), ('castName', 'Neil Patrick Harris')]
# [('seasonName', 'How I Met Your Mother, season 1'), ('epName', 'The Pineapple Incident'), ('castName', 'Neil Patrick Harris')]
# [('seasonName', 'How I Met Your Mother, season 1'), ('epName', 'Zip, Zip, Zip'), ('castName', 'Neil Patrick Harris')]
# [('seasonName', 'How I Met Your Mother, season 1'), ('epName', 'Best Prom Ever'), ('castName', 'Neil Patrick Harris')]
# [('seasonName', 'How I Met Your Mother, season 1'), ('epName', 'Matchmaker'), ('castName', 'Neil Patrick Harris')]
# [('seasonName', 'How I Met Your Mother, season 1'), ('epName', 'Slutty Pumpkin'), ('castName', 'Neil Patrick Harris')]
# [('seasonName', 'How I Met Your Mother, season 1'), ('epName', 'Matchmaker'), ('castName', 'Camryn Manheim')]
# [('seasonName', 'How I Met Your Mother, season 1'), ('epName', 'Return of the Shirt'), ('castName', 'Charlene Amoia')]
# [('seasonName', 'How I Met Your Mother, season 1'), ('epName', 'Milk'), ('castName', 'Charlene Amoia')]
# [('seasonName', 'How I Met Your Mother, season 1'), ('epName', 'Nothing Good Happens After 2 A.M.'), ('castName', 'Josh Radnor')]
# [('seasonName', 'How I Met Your Mother, season 1'), ('epName', 'Okay Awesome'), ('castName', 'Josh Radnor')]
# [('seasonName', 'How I Met Your Mother, season 1'), ('epName', 'Return of the Shirt'), ('castName', 'Josh Radnor')]
# [('seasonName', 'How I Met Your Mother, season 1'), ('epName', 'Pilot'), ('castName', 'Josh Radnor')]
# [('seasonName', 'How I Met Your Mother, season 1'), ('epName', 'Purple Giraffe'), ('castName', 'Josh Radnor')]
# [('seasonName', 'How I Met Your Mother, season 1'), ('epName', 'Sweet Taste of Liberty'), ('castName', 'Josh Radnor')]
# [('seasonName', 'How I Met Your Mother, season 1'), ('epName', 'Game Night'), ('castName', 'Josh Radnor')]
# [('seasonName', 'How I Met Your Mother, season 1'), ('epName', 'Drumroll, Please'), ('castName', 'Josh Radnor')]
# [('seasonName', 'How I Met Your Mother, season 1'), ('epName', 'Life Among the Gorillas'), ('castName', 'Josh Radnor')]
# [('seasonName', 'How I Met Your Mother, season 1'), ('epName', 'Cupcake'), ('castName', 'Josh Radnor')]
# [('seasonName', 'How I Met Your Mother, season 1'), ('epName', 'The Wedding'), ('castName', 'Josh Radnor')]
# [('seasonName', 'How I Met Your Mother, season 1'), ('epName', 'Belly Full of Turkey'), ('castName', 'Josh Radnor')]
# [('seasonName', 'How I Met Your Mother, season 1'), ('epName', 'Come On'), ('castName', 'Josh Radnor')]
# [('seasonName', 'How I Met Your Mother, season 1'), ('epName', 'Mary the Paralegal'), ('castName', 'Josh Radnor')]
# [('seasonName', 'How I Met Your Mother, season 1'), ('epName', 'Milk'), ('castName', 'Josh Radnor')]
# [('seasonName', 'How I Met Your Mother, season 1'), ('epName', 'The Duel'), ('castName', 'Josh Radnor')]
# [('seasonName', 'How I Met Your Mother, season 1'), ('epName', 'The Limo'), ('castName', 'Josh Radnor')]
# [('seasonName', 'How I Met Your Mother, season 1'), ('epName', 'The Pineapple Incident'), ('castName', 'Josh Radnor')]
# [('seasonName', 'How I Met Your Mother, season 1'), ('epName', 'Zip, Zip, Zip'), ('castName', 'Josh Radnor')]
# [('seasonName', 'How I Met Your Mother, season 1'), ('epName', 'Best Prom Ever'), ('castName', 'Josh Radnor')]
# [('seasonName', 'How I Met Your Mother, season 1'), ('epName', 'Matchmaker'), ('castName', 'Josh Radnor')]
# [('seasonName', 'How I Met Your Mother, season 1'), ('epName', 'Slutty Pumpkin'), ('castName', 'Josh Radnor')]
# [('seasonName', 'How I Met Your Mother, season 1'), ('epName', 'Game Night'), ('castName', 'Suzie Plakson')]
# [('seasonName', 'How I Met Your Mother, season 1'), ('epName', 'Belly Full of Turkey'), ('castName', 'Suzie Plakson')]
# [('seasonName', 'How I Met Your Mother, season 1'), ('epName', 'Nothing Good Happens After 2 A.M.'), ('castName', 'Alyson Hannigan')]
# [('seasonName', 'How I Met Your Mother, season 1'), ('epName', 'Okay Awesome'), ('castName', 'Alyson Hannigan')]
# [('seasonName', 'How I Met Your Mother, season 1'), ('epName', 'Return of the Shirt'), ('castName', 'Alyson Hannigan')]
# [('seasonName', 'How I Met Your Mother, season 1'), ('epName', 'Pilot'), ('castName', 'Alyson Hannigan')]
# [('seasonName', 'How I Met Your Mother, season 1'), ('epName', 'Purple Giraffe'), ('castName', 'Alyson Hannigan')]
# [('seasonName', 'How I Met Your Mother, season 1'), ('epName', 'Sweet Taste of Liberty'), ('castName', 'Alyson Hannigan')]
# [('seasonName', 'How I Met Your Mother, season 1'), ('epName', 'Game Night'), ('castName', 'Alyson Hannigan')]
# [('seasonName', 'How I Met Your Mother, season 1'), ('epName', 'Drumroll, Please'), ('castName', 'Alyson Hannigan')]
# [('seasonName', 'How I Met Your Mother, season 1'), ('epName', 'Life Among the Gorillas'), ('castName', 'Alyson Hannigan')]
# [('seasonName', 'How I Met Your Mother, season 1'), ('epName', 'Cupcake'), ('castName', 'Alyson Hannigan')]
# [('seasonName', 'How I Met Your Mother, season 1'), ('epName', 'The Wedding'), ('castName', 'Alyson Hannigan')]
# [('seasonName', 'How I Met Your Mother, season 1'), ('epName', 'Belly Full of Turkey'), ('castName', 'Alyson Hannigan')]
# [('seasonName', 'How I Met Your Mother, season 1'), ('epName', 'Come On'), ('castName', 'Alyson Hannigan')]
# 100

# %% [markdown]
# Final query for this task

# %%
# write your final query
# P527 has part
# Q2472427 
## Q147235	How I met your mother

queryString = """ 
SELECT DISTINCT ?cast ?castName (count(distinct ?ep) as ?countEp)
WHERE {
   # bind something
   wd:Q147235 wdt:P527 ?season.
   
   # ?season wdt:P527 ?ep. # trovo gli episodi della serie
   
   # ?ep wdt:P161 ?cast.
       
  
   
   # get the label
   #?people sc:name ?peopleName.
   # ?ep sc:name ?epName.
   # ?cast sc:name ?castName.
   # ?season sc:name ?seasonName.
   
   
}

group by ?cast ?castName
order by ?castName
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('cast', 'http://www.wikidata.org/entity/Q8349'), ('castName', '"Weird Al" Yankovic'), ('countEp', '1')]
# [('cast', 'http://www.wikidata.org/entity/Q667979'), ('castName', 'Aaron Hill'), ('countEp', '1')]
# [('cast', 'http://www.wikidata.org/entity/Q321131'), ('castName', 'Abigail Spencer'), ('countEp', '1')]
# [('cast', 'http://www.wikidata.org/entity/Q151866'), ('castName', 'Adriana Lima'), ('countEp', '1')]
# [('cast', 'http://www.wikidata.org/entity/Q2827976'), ('castName', 'Ailsa Marshall'), ('countEp', '1')]
# [('cast', 'http://www.wikidata.org/entity/Q2636696'), ('castName', 'Alan Fudge'), ('countEp', '1')]
# [('cast', 'http://www.wikidata.org/entity/Q277895'), ('castName', 'Alan Thicke'), ('countEp', '3')]
# [('cast', 'http://www.wikidata.org/entity/Q16729414'), ('castName', 'Alec Gray'), ('countEp', '1')]
# [('cast', 'http://www.wikidata.org/entity/Q366322'), ('castName', 'Alexis Denisof'), ('countEp', '5')]
# [('cast', 'http://www.wikidata.org/entity/Q199927'), ('castName', 'Alyson Hannigan'), ('countEp', '143')]
# [('cast', 'http://www.wikidata.org/entity/Q450496'), ('castName', 'Alyssa Shafer'), ('countEp', '1')]
# [('cast', 'http://www.wikidata.org/entity/Q131332'), ('castName', 'Amanda Peet'), ('countEp', '1')]
# [('cast', 'http://www.wikidata.org/entity/Q444146'), ('castName', 'Amber Stevens'), ('countEp', '1')]
# [('cast', 'http://www.wikidata.org/entity/Q2842824'), ('castName', 'America Olivo'), ('countEp', '1')]
# [('cast', 'http://www.wikidata.org/entity/Q152773'), ('castName', 'Amy Acker'), ('countEp', '1')]
# [('cast', 'http://www.wikidata.org/entity/Q2844557'), ('castName', 'Amy Gumenick'), ('countEp', '1')]
# [('cast', 'http://www.wikidata.org/entity/Q236918'), ('castName', 'Anne Dudek'), ('countEp', '2')]
# [('cast', 'http://www.wikidata.org/entity/Q465556'), ('castName', 'Annie Ilonzeh'), ('countEp', '1')]
# [('cast', 'http://www.wikidata.org/entity/Q264787'), ('castName', 'April Bowlby'), ('countEp', '3')]
# [('cast', 'http://www.wikidata.org/entity/Q435839'), ('castName', 'Ashley Williams'), ('countEp', '9')]
# [('cast', 'http://www.wikidata.org/entity/Q17428816'), ('castName', 'Austin Majors'), ('countEp', '1')]
# [('cast', 'http://www.wikidata.org/entity/Q770841'), ('castName', 'Ben Vereen'), ('countEp', '2')]
# [('cast', 'http://www.wikidata.org/entity/Q258237'), ('castName', 'Beth Riesgraf'), ('countEp', '1')]
# [('cast', 'http://www.wikidata.org/entity/Q458582'), ('castName', 'Betsy Rue'), ('countEp', '1')]
# [('cast', 'http://www.wikidata.org/entity/Q591238'), ('castName', 'Bill Fagerbakke'), ('countEp', '9')]
# [('cast', 'http://www.wikidata.org/entity/Q247064'), ('castName', 'Bill Macy'), ('countEp', '1')]
# [('cast', 'http://www.wikidata.org/entity/Q2903362'), ('castName', 'Bill Suplee'), ('countEp', '1')]
# [('cast', 'http://www.wikidata.org/entity/Q888178'), ('castName', 'Bob Odenkirk'), ('countEp', '7')]
# [('cast', 'http://www.wikidata.org/entity/Q333544'), ('castName', 'Bob Saget'), ('countEp', '142')]
# [('cast', 'http://www.wikidata.org/entity/Q733691'), ('castName', 'Brad Rowe'), ('countEp', '1')]
# [('cast', 'http://www.wikidata.org/entity/Q11975'), ('castName', 'Britney Spears'), ('countEp', '2')]
# [('cast', 'http://www.wikidata.org/entity/Q459839'), ('castName', "Brooke D'Orsay"), ('countEp', '1')]
# [('cast', 'http://www.wikidata.org/entity/Q254775'), ('castName', 'Brooke Nevin'), ('countEp', '1')]
# [('cast', 'http://www.wikidata.org/entity/Q968718'), ('castName', 'Bruce Gray'), ('countEp', '1')]
# [('cast', 'http://www.wikidata.org/entity/Q1139526'), ('castName', 'Bryan Callen'), ('countEp', '6')]
# [('cast', 'http://www.wikidata.org/entity/Q23547'), ('castName', 'Bryan Cranston'), ('countEp', '2')]
# [('cast', 'http://www.wikidata.org/entity/Q235740'), ('castName', 'Busy Philipps'), ('countEp', '1')]
# [('cast', 'http://www.wikidata.org/entity/Q234514'), ('castName', 'Camryn Manheim'), ('countEp', '1')]
# [('cast', 'http://www.wikidata.org/entity/Q39574'), ('castName', 'Candice King'), ('countEp', '1')]
# [('cast', 'http://www.wikidata.org/entity/Q1809038'), ('castName', 'Caroline Lagerfelt'), ('countEp', '1')]
# [('cast', 'http://www.wikidata.org/entity/Q215546'), ('castName', 'Carrie Underwood'), ('countEp', '1')]
# [('cast', 'http://www.wikidata.org/entity/Q2656047'), ('castName', 'Carter Bays'), ('countEp', '1')]
# [('cast', 'http://www.wikidata.org/entity/Q2942050'), ('castName', 'Catherine Reitman'), ('countEp', '1')]
# [('cast', 'http://www.wikidata.org/entity/Q16149506'), ('castName', 'Charlene Amoia'), ('countEp', '17')]
# [('cast', 'http://www.wikidata.org/entity/Q456258'), ('castName', 'Charles Robinson'), ('countEp', '1')]
# [('cast', 'http://www.wikidata.org/entity/Q471128'), ('castName', 'Chi McBride'), ('countEp', '1')]
# [('cast', 'http://www.wikidata.org/entity/Q377424'), ('castName', 'Chris Elliott'), ('countEp', '3')]
# [('cast', 'http://www.wikidata.org/entity/Q741909'), ('castName', 'Chris Kattan'), ('countEp', '1')]
# [('cast', 'http://www.wikidata.org/entity/Q3675563'), ('castName', 'Chris Romano'), ('countEp', '4')]
# [('cast', 'http://www.wikidata.org/entity/Q238117'), ('castName', 'Christina Pickles'), ('countEp', '1')]
# [('cast', 'http://www.wikidata.org/entity/Q290156'), ('castName', 'Christine Woods'), ('countEp', '1')]
# [('cast', 'http://www.wikidata.org/entity/Q200566'), ('castName', 'Cobie Smulders'), ('countEp', '145')]
# [('cast', 'http://www.wikidata.org/entity/Q2604240'), ('castName', 'Collette Wolfe'), ('countEp', '1')]
# [('cast', 'http://www.wikidata.org/entity/Q761697'), ('castName', 'Connie Sawyer'), ('countEp', '1')]
# [('cast', 'http://www.wikidata.org/entity/Q1189095'), ('castName', 'Courtney Ford'), ('countEp', '1')]
# [('cast', 'http://www.wikidata.org/entity/Q3002075'), ('castName', 'Craig Thomas'), ('countEp', '1')]
# [('cast', 'http://www.wikidata.org/entity/Q5186320'), ('castName', 'Cristin Milioti'), ('countEp', '3')]
# [('cast', 'http://www.wikidata.org/entity/Q238425'), ('castName', 'Cristine Rose'), ('countEp', '5')]
# [('cast', 'http://www.wikidata.org/entity/Q5213110'), ('castName', 'Dan Bakkedahl'), ('countEp', '1')]
# [('cast', 'http://www.wikidata.org/entity/Q44442'), ('castName', 'Dan Castellaneta'), ('countEp', '1')]
# [('cast', 'http://www.wikidata.org/entity/Q1159104'), ('castName', 'Dan Lauria'), ('countEp', '1')]
# [('cast', 'http://www.wikidata.org/entity/Q242949'), ('castName', 'Danica McKellar'), ('countEp', '2')]
# [('cast', 'http://www.wikidata.org/entity/Q230176'), ('castName', 'Danneel Ackles'), ('countEp', '3')]
# [('cast', 'http://www.wikidata.org/entity/Q192165'), ('castName', 'Danny Glover'), ('countEp', '1')]
# [('cast', 'http://www.wikidata.org/entity/Q784009'), ('castName', 'Danny Strong'), ('countEp', '1')]
# [('cast', 'http://www.wikidata.org/entity/Q448484'), ('castName', 'Darby Stanchfield'), ('countEp', '1')]
# [('cast', 'http://www.wikidata.org/entity/Q454698'), ('castName', 'Darcy Rose Byrnes'), ('countEp', '5')]
# [('cast', 'http://www.wikidata.org/entity/Q984397'), ('castName', 'David Burtka'), ('countEp', '5')]
# [('cast', 'http://www.wikidata.org/entity/Q297128'), ('castName', 'David Henrie'), ('countEp', '48')]
# [('cast', 'http://www.wikidata.org/entity/Q348986'), ('castName', 'Davis Cleveland'), ('countEp', '1')]
# [('cast', 'http://www.wikidata.org/entity/Q279816'), ('castName', 'Dawn Olivieri'), ('countEp', '2')]
# [('cast', 'http://www.wikidata.org/entity/Q240720'), ('castName', 'Deanna Russo'), ('countEp', '1')]
# [('cast', 'http://www.wikidata.org/entity/Q924222'), ('castName', 'Diane Salinger'), ('countEp', '1')]
# [('cast', 'http://www.wikidata.org/entity/Q3306283'), ('castName', 'Dwight Hicks'), ('countEp', '1')]
# [('cast', 'http://www.wikidata.org/entity/Q439070'), ('castName', 'E. E. Bell'), ('countEp', '2')]
# [('cast', 'http://www.wikidata.org/entity/Q5334589'), ('castName', 'Ed Brigadier'), ('countEp', '1')]
# [('cast', 'http://www.wikidata.org/entity/Q444480'), ('castName', 'Elizabeth Bogush'), ('countEp', '1')]
# [('cast', 'http://www.wikidata.org/entity/Q3052368'), ('castName', 'Emily Baldoni'), ('countEp', '1')]
# [('cast', 'http://www.wikidata.org/entity/Q922264'), ('castName', 'Eric Allan Kramer'), ('countEp', '1')]
# [('cast', 'http://www.wikidata.org/entity/Q614851'), ('castName', 'Eric Braeden'), ('countEp', '1')]
# [('cast', 'http://www.wikidata.org/entity/Q2633899'), ('castName', 'Erin Cahill'), ('countEp', '1')]
# [('cast', 'http://www.wikidata.org/entity/Q289330'), ('castName', 'Erin Cardillo'), ('countEp', '1')]
# [('cast', 'http://www.wikidata.org/entity/Q525572'), ('castName', 'Erinn Bartlett'), ('countEp', '1')]
# [('cast', 'http://www.wikidata.org/entity/Q260184'), ('castName', 'Eva Amurri'), ('countEp', '1')]
# [('cast', 'http://www.wikidata.org/entity/Q4993338'), ('castName', 'Ezra Buzzington'), ('countEp', '1')]
# [('cast', 'http://www.wikidata.org/entity/Q233882'), ('castName', 'Frances Conroy'), ('countEp', '3')]
# [('cast', 'http://www.wikidata.org/entity/Q376031'), ('castName', 'Gary Anthony Williams'), ('countEp', '1')]
# [('cast', 'http://www.wikidata.org/entity/Q3099305'), ('castName', 'Gattlin Griffith'), ('countEp', '1')]
# [('cast', 'http://www.wikidata.org/entity/Q255293'), ('castName', 'Geoff Stults'), ('countEp', '2')]
# [('cast', 'http://www.wikidata.org/entity/Q3045427'), ('castName', 'George Cheung'), ('countEp', '1')]
# [('cast', 'http://www.wikidata.org/entity/Q566885'), ('castName', 'Harry Groener'), ('countEp', '2')]
# [('cast', 'http://www.wikidata.org/entity/Q446481'), ('castName', 'Harvey Fierstein'), ('countEp', '1')]
# [('cast', 'http://www.wikidata.org/entity/Q229349'), ('castName', 'Heather Morris'), ('countEp', '1')]
# [('cast', 'http://www.wikidata.org/entity/Q60036'), ('castName', 'Heidi Klum'), ('countEp', '1')]
# [('cast', 'http://www.wikidata.org/entity/Q1402293'), ('castName', 'Italia Ricci'), ('countEp', '1')]
# [('cast', 'http://www.wikidata.org/entity/Q1459918'), ('castName', 'James Tupper'), ('countEp', '1')]
# [('cast', 'http://www.wikidata.org/entity/Q313392'), ('castName', 'James Van Der Beek'), ('countEp', '1')]
# [('cast', 'http://www.wikidata.org/entity/Q234715'), ('castName', 'Jamie-Lynn Sigler'), ('countEp', '1')]
# [('cast', 'http://www.wikidata.org/entity/Q123849'), ('castName', 'Jane Seymour'), ('countEp', '1')]
# [('cast', 'http://www.wikidata.org/entity/Q1255263'), ('castName', 'Jason Jones'), ('countEp', '4')]
# 100

# %% [markdown]
# ## Task 4
# Check who is the actor who acted in more films while working on "How I met your mother" (the result set must be a list of triples actor/actress IRI, label and #films).

# %%
# write your queries
# troviamo la lista dei film 
# P161  'cast member' 
# wd:Q147235 HIMYM
queryString = """
SELECT DISTINCT  ?actor ?actorName
WHERE {
   
   
   wd:Q147235 wdt:P161 ?actor.
  
  
}
LIMIT 10
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('actor', 'http://www.wikidata.org/entity/Q465556')]
# [('actor', 'http://www.wikidata.org/entity/Q269891')]
# [('actor', 'http://www.wikidata.org/entity/Q4888924')]
# [('actor', 'http://www.wikidata.org/entity/Q446031')]
# [('actor', 'http://www.wikidata.org/entity/Q312705')]
# [('actor', 'http://www.wikidata.org/entity/Q469579')]
# [('actor', 'http://www.wikidata.org/entity/Q516659')]
# [('actor', 'http://www.wikidata.org/entity/Q522856')]
# [('actor', 'http://www.wikidata.org/entity/Q200566')]
# [('actor', 'http://www.wikidata.org/entity/Q435839')]
# 10

# %%
# write your queries
# troviamo la lista dei film 
# P161  'cast member' 
# wd:Q147235 HIMYM


queryString = """
SELECT DISTINCT  ?actor ?actorName  ?film ?filmName
WHERE {
   
   
   wd:Q147235 wdt:P161 ?actor.
   # ?film wdt:P161 ?actor.
  
  # ?actor sc:name ?actorName.
  # ?film sc:name ?filmName.
  
}
group by ?actor ?actorName
LIMIT 10
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('actor', 'http://www.wikidata.org/entity/Q50737052'), ('actorName', 'K.T. Tatara'), ('film', 'http://www.wikidata.org/entity/Q147235'), ('filmName', 'How I Met Your Mother')]
# [('actor', 'http://www.wikidata.org/entity/Q167696'), ('actorName', 'Nicole Scherzinger'), ('film', 'http://www.wikidata.org/entity/Q327713'), ('filmName', 'Men in Black 3')]
# [('actor', 'http://www.wikidata.org/entity/Q2633899'), ('actorName', 'Erin Cahill'), ('film', 'http://www.wikidata.org/entity/Q6176596'), ('filmName', 'Jekyll')]
# [('actor', 'http://www.wikidata.org/entity/Q485310'), ('actorName', 'Neil Patrick Harris'), ('film', 'http://www.wikidata.org/entity/Q3480575'), ('filmName', 'Return of the Shirt')]
# [('actor', 'http://www.wikidata.org/entity/Q44442'), ('actorName', 'Dan Castellaneta'), ('film', 'http://www.wikidata.org/entity/Q797839'), ('filmName', 'Baby Daddy')]
# [('actor', 'http://www.wikidata.org/entity/Q433355'), ('actorName', 'Patricia Belcher'), ('film', 'http://www.wikidata.org/entity/Q1123479'), ('filmName', 'The Number 23')]
# [('actor', 'http://www.wikidata.org/entity/Q40715'), ('actorName', 'Jennifer Lopez'), ('film', 'http://www.wikidata.org/entity/Q945456'), ('filmName', 'Feel the Noise')]
# [('actor', 'http://www.wikidata.org/entity/Q39574'), ('actorName', 'Candice King'), ('film', 'http://www.wikidata.org/entity/Q28537'), ('filmName', 'The Vampire Diaries')]
# [('actor', 'http://www.wikidata.org/entity/Q471018'), ('actorName', 'Ernie Hudson'), ('film', 'http://www.wikidata.org/entity/Q1754442'), ('filmName', 'The Watcher')]
# [('actor', 'http://www.wikidata.org/entity/Q312705'), ('actorName', 'John Cho'), ('film', 'http://www.wikidata.org/entity/Q20649291'), ('filmName', 'Get a Job')]
# 10

# %%
# query example

queryString = """
SELECT DISTINCT ?p ?name ?obj
WHERE {
   # bind something
   wd:Q147235 ?p ?obj .
   # get the label
   # ?p sc:name ?name.
   filter regex (?name , "start time").
   
   
}
LIMIT 1000
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P580'), ('name', 'start time'), ('obj', '2005-09-19T00:00:00Z')]
# 1

# %%
# query example

queryString = """
SELECT DISTINCT ?p ?name ?obj
WHERE {
   # bind something
   wd:Q147235 ?p ?obj .
   # get the label
   # ?p sc:name ?name.
   filter regex (?name , "end time").
   
   
}
LIMIT 1000
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P582'), ('name', 'end time'), ('obj', '2014-03-31T00:00:00Z')]
# 1

# %% [markdown]
# Final query for this task

# %%
# P582 'end time'
# P580 'start time'
# write your queries
# troviamo la lista dei film 
# P161  'cast member' 
# wd:Q147235 HIMYM


queryString = """
SELECT DISTINCT  ?actor ?actorName  ?film ?filmName
WHERE {
   
   
   wd:Q147235 wdt:P161 ?actor.
   # ?film wdt:P161 ?actor;
       wdt:P582 ?endTimeFilm.
   wd:Q147235 wdt:P580 ?startTime;
       wdt:P582 ?endTime.
    
  
  # ?actor sc:name ?actorName.
  # ?film sc:name ?filmName.
  
  filter (?startTime < ?endTimeFilm && ?endTime > ?endTimeFilm).
  
}
group by ?actor ?actorName
LIMIT 10
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('actor', 'http://www.wikidata.org/entity/Q3306283'), ('actorName', 'Dwight Hicks'), ('film', 'http://www.wikidata.org/entity/Q733960'), ('filmName', 'Cold Case')]
# [('actor', 'http://www.wikidata.org/entity/Q289330'), ('actorName', 'Erin Cardillo'), ('film', 'http://www.wikidata.org/entity/Q139849'), ('filmName', 'The Suite Life on Deck')]
# [('actor', 'http://www.wikidata.org/entity/Q231091'), ('actorName', 'Morena Baccarin'), ('film', 'http://www.wikidata.org/entity/Q470111'), ('filmName', 'Medium')]
# [('actor', 'http://www.wikidata.org/entity/Q469579'), ('actorName', 'Mircea Monroe'), ('film', 'http://www.wikidata.org/entity/Q2293'), ('filmName', 'Chuck')]
# [('actor', 'http://www.wikidata.org/entity/Q3943077'), ('actorName', 'Ryan Michelle Bathe'), ('film', 'http://www.wikidata.org/entity/Q283393'), ('filmName', 'Private Practice')]
# [('actor', 'http://www.wikidata.org/entity/Q2627090'), ('actorName', 'Dave Thomas'), ('film', 'http://www.wikidata.org/entity/Q23609'), ('filmName', 'Weeds')]
# [('actor', 'http://www.wikidata.org/entity/Q1319539'), ('actorName', 'Thomas Lennon'), ('film', 'http://www.wikidata.org/entity/Q13218438'), ('filmName', 'Sean Saves the World')]
# [('actor', 'http://www.wikidata.org/entity/Q269891'), ('actorName', 'Julianna Guill'), ('film', 'http://www.wikidata.org/entity/Q10290188'), ('filmName', 'Glory Daze')]
# [('actor', 'http://www.wikidata.org/entity/Q255293'), ('actorName', 'Geoff Stults'), ('film', 'http://www.wikidata.org/entity/Q1891872'), ('filmName', 'October Road')]
# [('actor', 'http://www.wikidata.org/entity/Q234152'), ('actorName', 'Becki Newton'), ('film', 'http://www.wikidata.org/entity/Q966757'), ('filmName', 'The Goodwin Games')]
# 10

# %%
# P582 'end time'
# P580 'start time'
# write your queries
# troviamo la lista dei film 
# P161  'cast member' 
# wd:Q147235 HIMYM


queryString = """
SELECT DISTINCT  ?actor ?actorName  (count (?film) as ?numFilm )
WHERE {
   
   
   wd:Q147235 wdt:P161 ?actor.
   # ?film wdt:P161 ?actor;
       wdt:P582 ?endTimeFilm.
   wd:Q147235 wdt:P580 ?startTime;
       wdt:P582 ?endTime.
    
  
  # ?actor sc:name ?actorName.
  # ?film sc:name ?filmName.
  
  filter (?startTime < ?endTimeFilm && ?endTime > ?endTimeFilm).
  
}
group by ?actor ?actorName
LIMIT 10
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('actor', 'http://www.wikidata.org/entity/Q3306283'), ('actorName', 'Dwight Hicks'), ('numFilm', '1')]
# [('actor', 'http://www.wikidata.org/entity/Q234152'), ('actorName', 'Becki Newton'), ('numFilm', '3')]
# [('actor', 'http://www.wikidata.org/entity/Q233042'), ('actorName', 'Nancy Travis'), ('numFilm', '2')]
# [('actor', 'http://www.wikidata.org/entity/Q635974'), ('actorName', 'Michael Trucco'), ('numFilm', '5')]
# [('actor', 'http://www.wikidata.org/entity/Q926420'), ('actorName', 'Robbie Amell'), ('numFilm', '1')]
# [('actor', 'http://www.wikidata.org/entity/Q1459918'), ('actorName', 'James Tupper'), ('numFilm', '4')]
# [('actor', 'http://www.wikidata.org/entity/Q1806933'), ('actorName', 'Rhys Darby'), ('numFilm', '1')]
# [('actor', 'http://www.wikidata.org/entity/Q73346'), ('actorName', 'Ralph Macchio'), ('numFilm', '1')]
# [('actor', 'http://www.wikidata.org/entity/Q2842824'), ('actorName', 'America Olivo'), ('numFilm', '1')]
# [('actor', 'http://www.wikidata.org/entity/Q463673'), ('actorName', 'Regis Philbin'), ('numFilm', '2')]
# 10

# %% [markdown]
# ## Task 5
# Compare HIMYM with the tv series "The Office (US)" in terms of number of seasons, episods and cast members (the result set must be two elements -one for each tv series- of tv series IRI, label, #seasons, #episodes and #cast members).

# %%
# write your queries
#wd:Q23831` | The Office (US)  

# Q147235	How I met your mother


queryString = """
SELECT * WHERE
{ 
{
    SELECT DISTINCT (count (?obj) as ?numSeasonHIMYM)
            WHERE {
               # bind something
               wd:Q23831 ?p ?obj .


               # get the label
               # ?p sc:name ?name
               optional{?obj sc:name ?objName.}
               filter regex(?objName, "season").

            }
            
            LIMIT 20
}
UNION
{
    SELECT DISTINCT (count (?obj) as ?numSeasonTheOffice)
            WHERE {
               # bind something
               wd:Q147235 ?p ?obj .


               # get the label
               # ?p sc:name ?name
               optional{?obj sc:name ?objName.}
               filter regex(?objName, "season").

            }
            
            LIMIT 20
}
}



"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('numSeasonHIMYM', '9')]
# [('numSeasonTheOffice', '9')]
# 2

# %%
# write your queries
#wd:Q23831` | The Office (US)  

# Q147235	How I met your mother


queryString = """
SELECT * WHERE
{ 
{
    SELECT ?IRI ?HIMYM (count (?obj) as ?numSeasonHIMYM)
            WHERE {
               # bind something
               wd:Q147235 ?p ?obj .


               # get the label
               
               # ?p sc:name ?name.
               wd:Q147235 sc:name ?HIMYM.
               
               optional{?obj sc:name ?objName.}
               filter regex(?objName, "season").
               
               BIND ((wd:Q147235) AS ?IRI).

            }
            GROUP BY ?HIMYM ?IRI
            LIMIT 20
            
}
UNION
{
    SELECT ?IRI ?TheOffice (count (?obj) as ?numSeasonTheOffice)
            WHERE {
               # bind something
               wd:Q23831 ?p ?obj .


               # get the label
               # ?p sc:name ?name.
               wd:Q23831 sc:name ?TheOffice.
               
               optional{?obj sc:name ?objName.}
               filter regex(?objName, "season").
               
               BIND ((wd:Q23831) AS ?IRI).

            }
            GROUP BY ?TheOffice ?IRI
            LIMIT 20
            
}
}
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('IRI', 'http://www.wikidata.org/entity/Q147235'), ('HIMYM', 'How I Met Your Mother'), ('numSeasonHIMYM', '9')]
# [('IRI', 'http://www.wikidata.org/entity/Q23831'), ('TheOffice', 'The Office'), ('numSeasonTheOffice', '9')]
# 2

# %%
# write your queries
#wd:Q23831` | The Office (US)  

# Q147235	How I met your mother

#P527 'has part'


queryString = """
SELECT * WHERE
{ 
{
    SELECT ?IRI ?HIMYM (count (?season) as ?numSeasonHIMYM) (count (?ep) as ?epCount)
            WHERE {
               
               wd:Q147235 wdt:P527 ?season.
               # ?season wdt:P527 ?ep.

              
               wd:Q147235 sc:name ?HIMYM.
               BIND ((wd:Q147235) AS ?IRI).

            }
            GROUP BY ?HIMYM ?IRI
            LIMIT 20
            
}
UNION
{
    SELECT ?IRI ?TheOffice (count (?obj) as ?numSeasonTheOffice)
            WHERE {
               # bind something
               wd:Q23831 ?p ?obj .


               # get the label
               # ?p sc:name ?name.
               wd:Q23831 sc:name ?TheOffice.
               
               optional{?obj sc:name ?objName.}
               filter regex(?objName, "season").
               
               BIND ((wd:Q23831) AS ?IRI).

            }
            GROUP BY ?TheOffice ?IRI
            LIMIT 20
            
}
}
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('IRI', 'http://www.wikidata.org/entity/Q147235'), ('HIMYM', 'How I Met Your Mother'), ('numSeasonHIMYM', '208'), ('epCount', '208')]
# [('IRI', 'http://www.wikidata.org/entity/Q23831'), ('TheOffice', 'The Office'), ('numSeasonTheOffice', '9')]
# 2

# %% [markdown]
# Final query for this task

# %%
# write your final query
# write your queries
#wd:Q23831` | The Office (US)  

# Q147235	How I met your mother

#P527 'has part'


queryString = """
SELECT * WHERE
{ 
{
    SELECT ?IRI ?HIMYM (count (?season) as ?numSeasonHIMYM) (count (?ep) as ?epCount)
            WHERE {
               
               wd:Q147235 wdt:P527 ?season.
               # ?season wdt:P527 ?ep.

              
               wd:Q147235 sc:name ?HIMYM.
               BIND ((wd:Q147235) AS ?IRI).

            }
            GROUP BY ?HIMYM ?IRI
            LIMIT 20
            
}
UNION
{
    SELECT ?IRI ?TheOffice (count (?season) as ?numSeasonTheOffice)(count (?ep) as ?epCount)
            WHERE {
              
               wd:Q23831 ?p ?season.
               # ?season wdt:P527 ?ep.

               wd:Q23831 sc:name ?TheOffice.
               BIND ((wd:Q23831) AS ?IRI).

            }
            GROUP BY ?TheOffice ?IRI
            LIMIT 20
            
}
}
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('IRI', 'http://www.wikidata.org/entity/Q147235'), ('HIMYM', 'How I Met Your Mother'), ('numSeasonHIMYM', '208'), ('epCount', '208')]
# [('IRI', 'http://www.wikidata.org/entity/Q23831'), ('epCount', '216'), ('TheOffice', 'The Office'), ('numSeasonTheOffice', '216')]
# 2

# %% [markdown]
# ## Task 6
# Return how many of the actors who are members of the cast of the tv series have [Kavin Bacon number](https://en.wikipedia.org/wiki/Six_Degrees_of_Kevin_Bacon#:~:text=Kevin%20Bacon%20himself%20has%20a,Bacon%20number%20is%20N%2B1.) equal to 2 (the result set must be a list of couples actor/actress IRI and label).

# %%
# Return a list of actor of the cast

# P161 cast member
# Q147235  'HIMYM'
queryString = """
SELECT DISTINCT ?actor ?objName 
WHERE {
   
   wd:Q147235 wdt:P161 ?actor .
  

   # ?actor sc:name ?objName.
   
}
ORDER BY ASC (?objName)
LIMIT 10
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('actor', 'http://www.wikidata.org/entity/Q8349'), ('objName', '"Weird Al" Yankovic')]
# [('actor', 'http://www.wikidata.org/entity/Q24576840'), ('objName', 'Aaron Hendry')]
# [('actor', 'http://www.wikidata.org/entity/Q667979'), ('objName', 'Aaron Hill')]
# [('actor', 'http://www.wikidata.org/entity/Q2708237'), ('objName', 'Abby Elliott')]
# [('actor', 'http://www.wikidata.org/entity/Q50736659'), ('objName', 'Abhi Sinha')]
# [('actor', 'http://www.wikidata.org/entity/Q321131'), ('objName', 'Abigail Spencer')]
# [('actor', 'http://www.wikidata.org/entity/Q50736705'), ('objName', 'Adam Paul')]
# [('actor', 'http://www.wikidata.org/entity/Q151866'), ('objName', 'Adriana Lima')]
# [('actor', 'http://www.wikidata.org/entity/Q2827706'), ('objName', "Ahna O'Reilly")]
# [('actor', 'http://www.wikidata.org/entity/Q2827976'), ('objName', 'Ailsa Marshall')]
# 10

# %%
# trovare Kevin Bacon
# Return a list of actor of the cast

# P161 cast member
# Q147235  'HIMYM'
queryString = """
SELECT DISTINCT ?actor ?nameActor 
WHERE {
   
    # ?film wdt:P161 ?actor .
  

   # ?actor sc:name ?nameActor.
   filter regex(?nameActor,"Kevin Bacon").
   
}
ORDER BY ASC (?objName)
LIMIT 10
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('actor', 'http://www.wikidata.org/entity/Q3454165'), ('nameActor', 'Kevin Bacon')]
# 1

# %%
#Q3454165 Kevin Bacon
# film di kevin bacon
#lista attori con keni bacon 1
queryString = """
SELECT DISTINCT ?film ?filmName ?actor ?nameActor
WHERE {
   
    # ?film wdt:P161 wd:Q3454165;
        wdt:P161 ?actor.
    
  

   # ?film sc:name ?filmName.
   # ?actor sc:name ?nameActor.
   
}
ORDER BY ASC (?objName)
LIMIT 10
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('film', 'http://www.wikidata.org/entity/Q48742976'), ('filmName', 'City on a Hill'), ('actor', 'http://www.wikidata.org/entity/Q15867224'), ('nameActor', "Mark O'Brien")]
# [('film', 'http://www.wikidata.org/entity/Q1189631'), ('filmName', 'The Following'), ('actor', 'http://www.wikidata.org/entity/Q16185788'), ('nameActor', 'Kyle Catlett')]
# [('film', 'http://www.wikidata.org/entity/Q519490'), ('filmName', 'Crazy, Stupid, Love.'), ('actor', 'http://www.wikidata.org/entity/Q269891'), ('nameActor', 'Julianna Guill')]
# [('film', 'http://www.wikidata.org/entity/Q16971610'), ('filmName', 'Black Mass'), ('actor', 'http://www.wikidata.org/entity/Q391359'), ('nameActor', 'David Harbour')]
# [('film', 'http://www.wikidata.org/entity/Q611535'), ('filmName', 'Novocaine'), ('actor', 'http://www.wikidata.org/entity/Q449580'), ('nameActor', 'Lynne Thigpen')]
# [('film', 'http://www.wikidata.org/entity/Q990987'), ('filmName', 'My One and Only'), ('actor', 'http://www.wikidata.org/entity/Q918866'), ('nameActor', 'Troy Garity')]
# [('film', 'http://www.wikidata.org/entity/Q691672'), ('filmName', 'Frost/Nixon'), ('actor', 'http://www.wikidata.org/entity/Q1101612'), ('nameActor', 'Clint Howard')]
# [('film', 'http://www.wikidata.org/entity/Q1917925'), ('filmName', 'My Dog Skip'), ('actor', 'http://www.wikidata.org/entity/Q1101612'), ('nameActor', 'Clint Howard')]
# [('film', 'http://www.wikidata.org/entity/Q1724723'), ('filmName', 'End of the Line'), ('actor', 'http://www.wikidata.org/entity/Q1101612'), ('nameActor', 'Clint Howard')]
# [('film', 'http://www.wikidata.org/entity/Q106428'), ('filmName', 'Apollo 13'), ('actor', 'http://www.wikidata.org/entity/Q1101612'), ('nameActor', 'Clint Howard')]
# 10

# %%
#Q3454165 Kevin Bacon
# film di kevin bacon
#lista attori con keni bacon 2
# Q147235	How I met your mother


queryString = """
SELECT DISTINCT ?actor2 ?nameActor2
WHERE {
   
    # ?film wdt:P161 wd:Q3454165;
        wdt:P161 ?actor1.
    
  
     wd:Q147235 wdt:P161 ?actor2.
     # ?film wdt:P161 ?actor1;
         wdt:P161 ?actor2.
     
    
   # ?actor2 sc:name ?nameActor2.
   
   # ?film sc:name ?filmName.
   # ?actor1 sc:name ?nameActor.
   
}
LIMIT 10
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('film', 'http://www.wikidata.org/entity/Q519490'), ('filmName', 'Crazy, Stupid, Love.'), ('actor2', 'http://www.wikidata.org/entity/Q269891'), ('nameActor2', 'Julianna Guill')]
# [('film', 'http://www.wikidata.org/entity/Q370893'), ('filmName', 'The Air I Breathe'), ('actor2', 'http://www.wikidata.org/entity/Q312705'), ('nameActor2', 'John Cho')]
# [('film', 'http://www.wikidata.org/entity/Q16167570'), ('filmName', 'Skum Rocks!'), ('actor2', 'http://www.wikidata.org/entity/Q234715'), ('nameActor2', 'Jamie-Lynn Sigler')]
# [('film', 'http://www.wikidata.org/entity/Q627533'), ('filmName', 'Footloose'), ('actor2', 'http://www.wikidata.org/entity/Q311271'), ('nameActor2', 'John Lithgow')]
# [('film', 'http://www.wikidata.org/entity/Q1476932'), ('filmName', 'Queens Logic'), ('actor2', 'http://www.wikidata.org/entity/Q234137'), ('nameActor2', 'Megan Mullally')]
# [('film', 'http://www.wikidata.org/entity/Q223596'), ('filmName', 'X-Men: First Class'), ('actor2', 'http://www.wikidata.org/entity/Q530646'), ('nameActor2', 'Ray Wise')]
# [('film', 'http://www.wikidata.org/entity/Q975358'), ('filmName', 'Stir of Echoes'), ('actor2', 'http://www.wikidata.org/entity/Q199929'), ('nameActor2', 'Jennifer Morrison')]
# [('film', 'http://www.wikidata.org/entity/Q17508638'), ('filmName', 'The Darkness'), ('actor2', 'http://www.wikidata.org/entity/Q199929'), ('nameActor2', 'Jennifer Morrison')]
# [('film', 'http://www.wikidata.org/entity/Q514348'), ('filmName', 'Flatliners'), ('actor2', 'http://www.wikidata.org/entity/Q433355'), ('nameActor2', 'Patricia Belcher')]
# [('film', 'http://www.wikidata.org/entity/Q19824612'), ('filmName', 'Cop Car'), ('actor2', 'http://www.wikidata.org/entity/Q234514'), ('nameActor2', 'Camryn Manheim')]
# 10

# %% [markdown]
# Final query for this task

# %%
# write your final query
#vado a togliere gli attori che hanno il numero 1 di kevin Bacon

#Q3454165 Kevin Bacon
# film di kevin bacon
#lista attori con keni bacon 2
# Q147235	How I met your mother


queryString = """
SELECT DISTINCT ?actor2 ?nameActor2
WHERE {
   
   
    # ?film1 wdt:P161 wd:Q3454165;
        wdt:P161 ?actor1.
    
  
     wd:Q147235 wdt:P161 ?actor2.
     # ?film wdt:P161 ?actor1;
         wdt:P161 ?actor2.
     
    
   # ?actor2 sc:name ?nameActor2.
   
   # ?film sc:name ?filmName.
   # ?actor1 sc:name ?nameActor.
   
   FILTER(?actor1 != ?actor2).
  
 
   
}
LIMIT 10
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('actor2', 'http://www.wikidata.org/entity/Q566037'), ('nameActor2', 'Scoot McNairy')]
# [('actor2', 'http://www.wikidata.org/entity/Q1992967'), ('nameActor2', 'John Getz')]
# [('actor2', 'http://www.wikidata.org/entity/Q260184'), ('nameActor2', 'Eva Amurri')]
# [('actor2', 'http://www.wikidata.org/entity/Q450496'), ('nameActor2', 'Alyssa Shafer')]
# [('actor2', 'http://www.wikidata.org/entity/Q231006'), ('nameActor2', 'Jayma Mays')]
# [('actor2', 'http://www.wikidata.org/entity/Q454698'), ('nameActor2', 'Darcy Rose Byrnes')]
# [('actor2', 'http://www.wikidata.org/entity/Q312705'), ('nameActor2', 'John Cho')]
# [('actor2', 'http://www.wikidata.org/entity/Q4888924'), ('nameActor2', 'Benjamin Koldyke')]
# [('actor2', 'http://www.wikidata.org/entity/Q235740'), ('nameActor2', 'Busy Philipps')]
# [('actor2', 'http://www.wikidata.org/entity/Q943613'), ('nameActor2', 'Samm Levine')]
# 10

# %% [markdown]
# ## Task 7
# Consider the actors who are members of the cast of HIMYM. Amongst the tv series which these actors acted return only those which received more than 2 awards (the result set must be triples of tv series IRI, label, #awards won).

# %%
# P161 cast member
# Q147235  'HIMYM'
# Q5398426 'television series'
queryString = """
SELECT DISTINCT ?televisionSeries ?televisionSeriesName
WHERE {
   
   wd:Q147235 wdt:P161 ?actor.
   # ?televisionSeries wdt:P161 ?actor;
       # ?type wd:Q5398426.
  

   # ?televisionSeries sc:name ?televisionSeriesName.
   
}
ORDER BY ASC (?objName)
LIMIT 10
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('televisionSeries', 'http://www.wikidata.org/entity/Q500769'), ('televisionSeriesName', 'Freaks and Geeks')]
# [('televisionSeries', 'http://www.wikidata.org/entity/Q17049828'), ('televisionSeriesName', 'Bad Samaritans')]
# [('televisionSeries', 'http://www.wikidata.org/entity/Q15072819'), ('televisionSeriesName', 'Halt and Catch Fire')]
# [('televisionSeries', 'http://www.wikidata.org/entity/Q15931555'), ('televisionSeriesName', 'Fargo')]
# [('televisionSeries', 'http://www.wikidata.org/entity/Q18151386'), ('televisionSeriesName', 'Kirby Buckets')]
# [('televisionSeries', 'http://www.wikidata.org/entity/Q643894'), ('televisionSeriesName', 'Suddenly Susan')]
# [('televisionSeries', 'http://www.wikidata.org/entity/Q111756'), ('televisionSeriesName', "Kickin' It")]
# [('televisionSeries', 'http://www.wikidata.org/entity/Q22908690'), ('televisionSeriesName', 'The Good Place')]
# [('televisionSeries', 'http://www.wikidata.org/entity/Q22908828'), ('televisionSeriesName', 'Haters Back Off')]
# [('televisionSeries', 'http://www.wikidata.org/entity/Q210676'), ('televisionSeriesName', 'Nashville')]
# 10

# %%
# P161 cast member
# Q147235  'HIMYM'
# Q5398426 'television series'
queryString = """
SELECT DISTINCT ?p ?pName ?o ?oName
WHERE {
   
   wd:Q147235 wdt:P161 ?actor.
   # ?televisionSeries wdt:P161 ?actor;
       # ?type wd:Q5398426.
    # ?televisionSeries ?p ?o.
  

   # ?televisionSeries sc:name ?televisionSeriesName.
   # ?p sc:name ?pName.
   # ?o sc:name ?oName.
   
}
ORDER BY ASC (?objName)
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P136'), ('pName', 'genre'), ('o', 'http://www.wikidata.org/entity/Q7168625'), ('oName', 'historical drama')]
# [('p', 'http://www.wikidata.org/prop/direct/P136'), ('pName', 'genre'), ('o', 'http://www.wikidata.org/entity/Q157443'), ('oName', 'comedy film')]
# [('p', 'http://www.wikidata.org/prop/direct/P136'), ('pName', 'genre'), ('o', 'http://www.wikidata.org/entity/Q859369'), ('oName', 'comedy-drama')]
# [('p', 'http://www.wikidata.org/prop/direct/P136'), ('pName', 'genre'), ('o', 'http://www.wikidata.org/entity/Q102430221'), ('oName', 'coming-of-age television program')]
# [('p', 'http://www.wikidata.org/prop/direct/P136'), ('pName', 'genre'), ('o', 'http://www.wikidata.org/entity/Q775344'), ('oName', 'teen drama')]
# [('p', 'http://www.wikidata.org/prop/direct/P1411'), ('pName', 'nominated for'), ('o', 'http://www.wikidata.org/entity/Q3045762'), ('oName', 'Primetime Emmy Award for Outstanding Writing for a Comedy Series')]
# [('p', 'http://www.wikidata.org/prop/direct/P1411'), ('pName', 'nominated for'), ('o', 'http://www.wikidata.org/entity/Q7669614'), ('oName', 'TCA Award for Outstanding Achievement in Drama')]
# [('p', 'http://www.wikidata.org/prop/direct/P1411'), ('pName', 'nominated for'), ('o', 'http://www.wikidata.org/entity/Q7669620'), ('oName', 'TCA Award for Outstanding New Program')]
# [('p', 'http://www.wikidata.org/prop/direct/P1411'), ('pName', 'nominated for'), ('o', 'http://www.wikidata.org/entity/Q7669628'), ('oName', 'TCA Heritage Award')]
# [('p', 'http://www.wikidata.org/prop/direct/P1411'), ('pName', 'nominated for'), ('o', 'http://www.wikidata.org/entity/Q7243495'), ('oName', 'Primetime Emmy Award for Outstanding Casting for a Comedy Series')]
# [('p', 'http://www.wikidata.org/prop/direct/P161'), ('pName', 'cast member'), ('o', 'http://www.wikidata.org/entity/Q234204'), ('oName', 'Linda Cardellini')]
# [('p', 'http://www.wikidata.org/prop/direct/P161'), ('pName', 'cast member'), ('o', 'http://www.wikidata.org/entity/Q943613'), ('oName', 'Samm Levine')]
# [('p', 'http://www.wikidata.org/prop/direct/P161'), ('pName', 'cast member'), ('o', 'http://www.wikidata.org/entity/Q6184097'), ('oName', 'Jerry Messing')]
# [('p', 'http://www.wikidata.org/prop/direct/P161'), ('pName', 'cast member'), ('o', 'http://www.wikidata.org/entity/Q235740'), ('oName', 'Busy Philipps')]
# [('p', 'http://www.wikidata.org/prop/direct/P161'), ('pName', 'cast member'), ('o', 'http://www.wikidata.org/entity/Q2313940'), ('oName', 'Becky Ann Baker')]
# [('p', 'http://www.wikidata.org/prop/direct/P161'), ('pName', 'cast member'), ('o', 'http://www.wikidata.org/entity/Q360663'), ('oName', 'Thomas F. Wilson')]
# [('p', 'http://www.wikidata.org/prop/direct/P161'), ('pName', 'cast member'), ('o', 'http://www.wikidata.org/entity/Q930117'), ('oName', 'Joe Flaherty')]
# [('p', 'http://www.wikidata.org/prop/direct/P161'), ('pName', 'cast member'), ('o', 'http://www.wikidata.org/entity/Q463489'), ('oName', 'Natasha Melnick')]
# [('p', 'http://www.wikidata.org/prop/direct/P161'), ('pName', 'cast member'), ('o', 'http://www.wikidata.org/entity/Q342636'), ('oName', 'John Francis Daley')]
# [('p', 'http://www.wikidata.org/prop/direct/P161'), ('pName', 'cast member'), ('o', 'http://www.wikidata.org/entity/Q220308'), ('oName', 'Seth Rogen')]
# 20

# %%
# P1411 'nominated for'
# P161 cast member
# Q147235  'HIMYM'
# Q5398426 'television series'
queryString = """
SELECT DISTINCT ?televisionSeries ?televisionSeriesName (count (?award) as ?award)
WHERE {
   
   wd:Q147235 wdt:P161 ?actor.
   # ?televisionSeries wdt:P161 ?actor;
       # ?type wd:Q5398426.
    # ?televisionSeries wdt:P1411 ?award.
  

   # ?televisionSeries sc:name ?televisionSeriesName.
   
  
   
}
LIMIT 10
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('televisionSeries', 'http://www.wikidata.org/entity/Q1064766'), ('televisionSeriesName', 'Mad TV'), ('award', '8')]
# [('televisionSeries', 'http://www.wikidata.org/entity/Q1571652'), ('televisionSeriesName', 'Dog with a Blog'), ('award', '1')]
# [('televisionSeries', 'http://www.wikidata.org/entity/Q117590'), ('televisionSeriesName', 'Beverly Hills, 90210'), ('award', '30')]
# [('televisionSeries', 'http://www.wikidata.org/entity/Q184342'), ('televisionSeriesName', 'Wizards of Waverly Place'), ('award', '4')]
# [('televisionSeries', 'http://www.wikidata.org/entity/Q1061246'), ('televisionSeriesName', 'Growing Pains'), ('award', '2')]
# [('televisionSeries', 'http://www.wikidata.org/entity/Q1584299'), ('televisionSeriesName', 'Happy Endings'), ('award', '1')]
# [('televisionSeries', 'http://www.wikidata.org/entity/Q23609'), ('televisionSeriesName', 'Weeds'), ('award', '240')]
# [('televisionSeries', 'http://www.wikidata.org/entity/Q139849'), ('televisionSeriesName', 'The Suite Life on Deck'), ('award', '3')]
# [('televisionSeries', 'http://www.wikidata.org/entity/Q1068952'), ('televisionSeriesName', 'St. Elsewhere'), ('award', '15')]
# [('televisionSeries', 'http://www.wikidata.org/entity/Q366375'), ('televisionSeriesName', 'Good luck, Charlie!'), ('award', '2')]
# 10

# %% [markdown]
# Final query for this task

# %%
# P1411 'nominated for'
# P161 cast member
# Q147235  'HIMYM'
# Q5398426 'television series'
queryString = """
SELECT DISTINCT ?televisionSeries ?televisionSeriesName (count (?award) as ?awards)
WHERE {
   
   wd:Q147235 wdt:P161 ?actor.
   # ?televisionSeries wdt:P161 ?actor;
       # ?type wd:Q5398426.
    # ?televisionSeries wdt:P1411 ?award.
  

   # ?televisionSeries sc:name ?televisionSeriesName.
 
  
   
}
GROUP BY ?televisionSeries ?televisionSeriesName
HAVING (count (?award) > 1)
LIMIT 10
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('televisionSeries', 'http://www.wikidata.org/entity/Q1066201'), ('televisionSeriesName', 'Make It or Break It'), ('awards', '6')]
# [('televisionSeries', 'http://www.wikidata.org/entity/Q564345'), ('televisionSeriesName', 'Person of Interest'), ('awards', '16')]
# [('televisionSeries', 'http://www.wikidata.org/entity/Q187239'), ('televisionSeriesName', 'Zeke and Luther'), ('awards', '2')]
# [('televisionSeries', 'http://www.wikidata.org/entity/Q366375'), ('televisionSeriesName', 'Good luck, Charlie!'), ('awards', '2')]
# [('televisionSeries', 'http://www.wikidata.org/entity/Q193462'), ('televisionSeriesName', 'Gilmore Girls'), ('awards', '156')]
# [('televisionSeries', 'http://www.wikidata.org/entity/Q386880'), ('televisionSeriesName', 'Castle'), ('awards', '78')]
# [('televisionSeries', 'http://www.wikidata.org/entity/Q1027097'), ('televisionSeriesName', 'Call Me Fitz'), ('awards', '2')]
# [('televisionSeries', 'http://www.wikidata.org/entity/Q390405'), ('televisionSeriesName', 'Nikita'), ('awards', '2')]
# [('televisionSeries', 'http://www.wikidata.org/entity/Q18925'), ('televisionSeriesName', "I'm in the Band"), ('awards', '3')]
# [('televisionSeries', 'http://www.wikidata.org/entity/Q485668'), ('televisionSeriesName', 'Scrubs'), ('awards', '98')]
# 10

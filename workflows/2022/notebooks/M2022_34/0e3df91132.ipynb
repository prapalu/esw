# %% [markdown]
# # General instructions
#
# The goal of the project is to materialize a set of **exploratory workloads** over a real-world, large-scale,  open-domain KG: [WikiData](https://www.wikidata.org/wiki/Wikidata:Main_Page)
#
# An exploratory workload  is composed by a set of queries, where each query is related to the information obtained previously.
#
# An exploratory workload starts with a usually vague, open ended question, and does not assume the person issuing the workload has a clear understanding of the data contained in the target database or its structure.
#
# Remeber that:
#
# 1. All the queries must run in the python notebook
# 2. You can use classes and properties only if you find them via a SPARQL query that must be present in the notebook
# 3. You do not delete useless queries. Keep everything that is synthatically valid
#
# ```
# ?p <http://schema.org/name> ?name .
# ```
#
#     is the BGP returning a human-readable name of a property or a class in Wikidata.

# %%
## SETUP used later

from SPARQLWrapper import SPARQLWrapper, JSON


prefixString = """
##-0e3df91132-##
PREFIX wd: <http://www.wikidata.org/entity/> 
PREFIX wdt: <http://www.wikidata.org/prop/direct/> 
PREFIX sc: <http://schema.org/>
"""

# select and construct queries
def run_query(queryString,verbose = True):
    to_run = prefixString + "\n" + queryString

    sparql = SPARQLWrapper("http://a256-gc1-03.srv.aau.dk:5820/sparql")
    sparql.setTimeout(300)
    sparql.setReturnFormat(JSON)
    sparql.setQuery(to_run)

    try :
        results = sparql.query()
        json_results = results.convert()
        if len(json_results['results']['bindings'])==0:
            print("Empty")
            return []
        array = []
        for bindings in json_results['results']['bindings']:
            app =  [ (var, value['value'])  for var, value in bindings.items() ] 
            if verbose:
                print( app)
            array.append(app)
        if verbose:
            print(len(array))
        return array

    except Exception as e :
        print("The operation failed", e)
    
# ASk queries
def run_ask_query(queryString):
    to_run = prefixString + "\n" + queryString

    sparql = SPARQLWrapper("http://a256-gc1-03.srv.aau.dk:5820/sparql")
    sparql.setTimeout(300)
    sparql.setReturnFormat(JSON)
    sparql.setQuery(to_run)

    try :
        return sparql.query().convert()

    except Exception as e :
        print("The operation failed", e)

# %% [markdown]
# # Sport Workflow Series ("Association Football Players explorative search")
#
# Consider the following exploratory information need:
#
# > investigate the association football players and find the main BGPs related to this sport. Compare players per countries, awards of the players and participation in the FIFA World Cup.
#
# **Important consideration: in wikidata, we are talking of ASSOCIATION FOOTBALL**

# %% [markdown]
# ## Useful URIs for the current workflow
# The following are given:
#
# | IRI           | Description   | Role      |
# | -----------   | -----------   |-----------|
# | `wdt:P1647`   | subproperty   | predicate |
# | `wdt:P31`     | instance of   | predicate |
# | `wdt:P106`    | profession    | predicate |
# | `wdt:P279`    | subclass      | predicate |
# | `wdt:P27`     | nationality   | predicate |
# | `wd:Q5`| Human       | node |
# | `wd:Q11571`| Cristiano Ronaldo       | node |

# %% [markdown]
# Also consider
#
# ```
# wd:Q11571 ?p ?obj .
# ```
#
# is the BGP to retrieve all **properties of Cristiano Ronaldo**
#
# Please consider that when you return a resource, you should return the IRI and the label of the resource. In particular, when the task require you to identify a BGP the result set must always be a list of couples IRI - label.
#
#
#
# The workload should:
#
#
# 1. Identify the BGP for association football player
#
# 2. Identify the BGP for association football club
#
# 3. Identify the BGP for association football league
#
# 4. Return for each european country the number of association football leagues (the result set must be a list of triples country IRI, label and #leagues).
#
# 5. Identify the BGP for the ballon d'Or award
#
# 6. Return the countries which have at least two different players of their nationality (consider the country of citizenship) who won the ballon d'Or (the result set must be a list of triples country IRI, label and #different players).
#
# 7. Identify the BGP of the FIFA World Cup
#
# 8. Who are the players who partecipated in more than 4 world's cup editions? (the result set must be a list of triples player IRI, label and #participations).
#
# 9. Consider the countries that won the FIFA World Cup at least twice. Find the players of those countries won the ballon d'Or (the result set must be a list of couples player IRI and label).

# %% [markdown]
# ## Task 1
# Identify the BGP for association football player

# %%
# query example
queryString = """
SELECT DISTINCT ?p ?name
WHERE {
   # bind something
   wd:Q11571 ?p ?obj.
   # get the label
   # ?p sc:name ?name.
}
LIMIT 200
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P1005'), ('name', 'Portuguese National Library ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1006'), ('name', 'Nationale Thesaurus voor Auteurs ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1015'), ('name', 'NORAF ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P103'), ('name', 'native language')]
# [('p', 'http://www.wikidata.org/prop/direct/P1038'), ('name', 'relative')]
# [('p', 'http://www.wikidata.org/prop/direct/P1050'), ('name', 'medical condition')]
# [('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('p', 'http://www.wikidata.org/prop/direct/P109'), ('name', 'signature')]
# [('p', 'http://www.wikidata.org/prop/direct/P118'), ('name', 'league')]
# [('p', 'http://www.wikidata.org/prop/direct/P1263'), ('name', 'NNDB people ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1266'), ('name', 'AlloCiné person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1273'), ('name', 'CANTIC ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1280'), ('name', 'CONOR.SI ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1284'), ('name', 'Munzinger person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1285'), ('name', 'Munzinger Sport number')]
# [('p', 'http://www.wikidata.org/prop/direct/P1296'), ('name', 'Gran Enciclopèdia Catalana ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1343'), ('name', 'described by source')]
# [('p', 'http://www.wikidata.org/prop/direct/P1344'), ('name', 'participant in')]
# [('p', 'http://www.wikidata.org/prop/direct/P1350'), ('name', 'number of matches played/races/starts')]
# [('p', 'http://www.wikidata.org/prop/direct/P1399'), ('name', 'convicted of')]
# [('p', 'http://www.wikidata.org/prop/direct/P1411'), ('name', 'nominated for')]
# [('p', 'http://www.wikidata.org/prop/direct/P1412'), ('name', 'languages spoken, written or signed')]
# [('p', 'http://www.wikidata.org/prop/direct/P1417'), ('name', 'Encyclopædia Britannica Online ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1447'), ('name', 'Sports-Reference.com Olympic athlete ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1469'), ('name', 'FIFA player ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1532'), ('name', 'country for sport')]
# [('p', 'http://www.wikidata.org/prop/direct/P1618'), ('name', 'sport number')]
# [('p', 'http://www.wikidata.org/prop/direct/P166'), ('name', 'award received')]
# [('p', 'http://www.wikidata.org/prop/direct/P1695'), ('name', 'NLP ID (unique)')]
# [('p', 'http://www.wikidata.org/prop/direct/P1741'), ('name', 'GTAA ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P18'), ('name', 'image')]
# [('p', 'http://www.wikidata.org/prop/direct/P1889'), ('name', 'different from')]
# [('p', 'http://www.wikidata.org/prop/direct/P19'), ('name', 'place of birth')]
# [('p', 'http://www.wikidata.org/prop/direct/P1971'), ('name', 'number of children')]
# [('p', 'http://www.wikidata.org/prop/direct/P2002'), ('name', 'Twitter username')]
# [('p', 'http://www.wikidata.org/prop/direct/P2003'), ('name', 'Instagram username')]
# [('p', 'http://www.wikidata.org/prop/direct/P2013'), ('name', 'Facebook ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2020'), ('name', 'WorldFootball.net player ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2031'), ('name', 'work period (start)')]
# [('p', 'http://www.wikidata.org/prop/direct/P2048'), ('name', 'height')]
# [('p', 'http://www.wikidata.org/prop/direct/P2067'), ('name', 'mass')]
# [('p', 'http://www.wikidata.org/prop/direct/P21'), ('name', 'sex or gender')]
# [('p', 'http://www.wikidata.org/prop/direct/P213'), ('name', 'ISNI')]
# [('p', 'http://www.wikidata.org/prop/direct/P214'), ('name', 'VIAF ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2163'), ('name', 'FAST ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2193'), ('name', 'Soccerbase player ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P22'), ('name', 'father')]
# [('p', 'http://www.wikidata.org/prop/direct/P227'), ('name', 'GND ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2276'), ('name', 'UEFA player ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2369'), ('name', 'Soccerway player ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P244'), ('name', 'Library of Congress authority ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2446'), ('name', 'Transfermarkt player ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P25'), ('name', 'mother')]
# [('p', 'http://www.wikidata.org/prop/direct/P2574'), ('name', 'National-Football-Teams.com player ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2600'), ('name', 'Geni.com profile ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2605'), ('name', 'ČSFD person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P268'), ('name', 'Bibliothèque nationale de France ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P269'), ('name', 'IdRef ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P27'), ('name', 'country of citizenship')]
# [('p', 'http://www.wikidata.org/prop/direct/P2924'), ('name', 'Great Russian Encyclopedia Online ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3043'), ('name', 'Scoresway soccer person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3047'), ('name', 'PlaymakerStats.com player ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('name', 'instance of')]
# [('p', 'http://www.wikidata.org/prop/direct/P3219'), ('name', 'Encyclopædia Universalis ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3221'), ('name', 'New York Times topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3222'), ('name', 'NE.se ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3342'), ('name', 'significant person')]
# [('p', 'http://www.wikidata.org/prop/direct/P3365'), ('name', 'Treccani ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3373'), ('name', 'sibling')]
# [('p', 'http://www.wikidata.org/prop/direct/P3388'), ('name', 'LittleSis people ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3417'), ('name', 'Quora topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3427'), ('name', 'AS.com athlete ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P345'), ('name', 'IMDb ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P349'), ('name', 'National Diet Library ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3509'), ('name', 'Dagens Nyheter topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3537'), ('name', 'FootballDatabase.eu player ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3553'), ('name', 'Zhihu topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3630'), ('name', 'Babelio author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3655'), ('name', 'BDFutbol player ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3665'), ('name', "L'Équipe football player ID")]
# [('p', 'http://www.wikidata.org/prop/direct/P3681'), ('name', 'ESPNFC.com player ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3726'), ('name', 'EU-Football.info player ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P373'), ('name', 'Commons category')]
# [('p', 'http://www.wikidata.org/prop/direct/P413'), ('name', 'position played on team / speciality')]
# [('p', 'http://www.wikidata.org/prop/direct/P4342'), ('name', 'Store norske leksikon ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P451'), ('name', 'unmarried partner')]
# [('p', 'http://www.wikidata.org/prop/direct/P4985'), ('name', 'TMDb person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5019'), ('name', 'Brockhaus Enzyklopädie online ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5034'), ('name', 'National Library of Korea ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5247'), ('name', 'Giant Bomb ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5284'), ('name', 'Douban movie celebrity ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5361'), ('name', 'BNB person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P54'), ('name', 'member of sports team')]
# [('p', 'http://www.wikidata.org/prop/direct/P5421'), ('name', 'Trading Card Database person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P551'), ('name', 'residence')]
# [('p', 'http://www.wikidata.org/prop/direct/P5587'), ('name', 'Libris-URI')]
# [('p', 'http://www.wikidata.org/prop/direct/P5617'), ('name', 'Evene ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P569'), ('name', 'date of birth')]
# [('p', 'http://www.wikidata.org/prop/direct/P5740'), ('name', 'So Foot ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5750'), ('name', 'FBref.com player ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6058'), ('name', 'Larousse ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6188'), ('name', 'BDFA player ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6327'), ('name', 'Goodreads character ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6379'), ('name', 'has works in the collection')]
# [('p', 'http://www.wikidata.org/prop/direct/P641'), ('name', 'sport')]
# [('p', 'http://www.wikidata.org/prop/direct/P646'), ('name', 'Freebase ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6509'), ('name', 'total goals in career')]
# [('p', 'http://www.wikidata.org/prop/direct/P6517'), ('name', 'WhoSampled artist ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6573'), ('name', 'Klexikon article ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6615'), ('name', 'Kicker.de player ID (former scheme)')]
# [('p', 'http://www.wikidata.org/prop/direct/P6849'), ('name', 'DR topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6868'), ('name', 'Hoopla artist ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P691'), ('name', 'NKCR AUT ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7293'), ('name', 'PLWABN ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P734'), ('name', 'family name')]
# [('p', 'http://www.wikidata.org/prop/direct/P735'), ('name', 'given name')]
# [('p', 'http://www.wikidata.org/prop/direct/P742'), ('name', 'pseudonym')]
# [('p', 'http://www.wikidata.org/prop/direct/P7666'), ('name', 'Visuotinė lietuvių enciklopedija ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7763'), ('name', 'copyright status as a creator')]
# [('p', 'http://www.wikidata.org/prop/direct/P7818'), ('name', 'French Vikidia ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7827'), ('name', 'Spanish Vikidia ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7829'), ('name', 'English Vikidia ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7859'), ('name', 'WorldCat Identities ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8286'), ('name', 'Olympedia people ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8349'), ('name', 'Proleksis enciklopedija ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P859'), ('name', 'sponsor')]
# [('p', 'http://www.wikidata.org/prop/direct/P8672'), ('name', 'Twitter topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8687'), ('name', 'social media followers')]
# [('p', 'http://www.wikidata.org/prop/direct/P8912'), ('name', 'Kicker.de player ID (actual scheme)')]
# [('p', 'http://www.wikidata.org/prop/direct/P898'), ('name', 'IPA transcription')]
# [('p', 'http://www.wikidata.org/prop/direct/P906'), ('name', 'SELIBR ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P910'), ('name', "topic's main category")]
# [('p', 'http://www.wikidata.org/prop/direct/P9368'), ('name', 'CNA topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P949'), ('name', 'National Library of Israel ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P950'), ('name', 'Biblioteca Nacional de España ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P9743'), ('name', 'Podchaser creator ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P9807'), ('name', 'SNK ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2458'), ('name', 'Mackolik.com player ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3579'), ('name', 'Sina Weibo user ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8780'), ('name', 'Portuguese Football Federation ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3046'), ('name', 'ForaDeJogo player ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7036'), ('name', 'TuttoCalciatori.net player ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8006'), ('name', 'footedness')]
# 143

# %%
#Using ID for Occupation to search
#[('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
queryString = """
SELECT DISTINCT ?p ?name
WHERE {
   # bind something
   wd:Q11571 wdt:P106 ?p .
   # get the label
   # ?p sc:name ?name.
}
LIMIT 200
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/entity/Q937857'), ('name', 'association football player')]
# 1

# %% [markdown]
# Final query for this task

# %%
# write your final query
# Using results from last query for BGP of Association Football Player
queryString = """
SELECT DISTINCT ?p ?name
WHERE {
   # bind something
   wd:Q937857 ?p ?obj.
   # get the label
   # ?p sc:name ?name.
}
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P1014'), ('name', 'Art & Architecture Thesaurus ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1149'), ('name', 'Library of Congress Classification')]
# [('p', 'http://www.wikidata.org/prop/direct/P1424'), ('name', "topic's main template")]
# [('p', 'http://www.wikidata.org/prop/direct/P1709'), ('name', 'equivalent class')]
# [('p', 'http://www.wikidata.org/prop/direct/P18'), ('name', 'image')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('name', 'properties for this type')]
# [('p', 'http://www.wikidata.org/prop/direct/P2163'), ('name', 'FAST ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P227'), ('name', 'GND ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2347'), ('name', 'YSO ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P244'), ('name', 'Library of Congress authority ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P268'), ('name', 'Bibliothèque nationale de France ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('name', 'subclass of')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('name', 'instance of')]
# [('p', 'http://www.wikidata.org/prop/direct/P361'), ('name', 'part of')]
# [('p', 'http://www.wikidata.org/prop/direct/P373'), ('name', 'Commons category')]
# [('p', 'http://www.wikidata.org/prop/direct/P425'), ('name', 'field of this occupation')]
# [('p', 'http://www.wikidata.org/prop/direct/P4946'), ('name', 'Library of Congress Demographic Group Terms ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P508'), ('name', 'BNCF Thesaurus ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5247'), ('name', 'Giant Bomb ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5844'), ('name', 'Treccani Vocabulary ID')]
# 20

# %% [markdown]
# ## Task 2
# Identify the BGP for association football club

# %%
# Using ID for Association football Player
queryString = """
SELECT DISTINCT ?p ?name
WHERE {
   # bind something
   wd:Q937857 ?obj ?p.
   # get the label
   # ?p sc:name ?name.
}
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/entity/P2369'), ('name', 'Soccerway player ID')]
# [('p', 'http://www.wikidata.org/entity/P3908'), ('name', 'Reprezentacija player ID')]
# [('p', 'http://www.wikidata.org/entity/Q18536342'), ('name', 'competitive player')]
# [('p', 'http://www.wikidata.org/entity/P2446'), ('name', 'Transfermarkt player ID')]
# [('p', 'http://www.wikidata.org/entity/Q7217464'), ('name', 'Category:Association football players')]
# [('p', 'http://www.wikidata.org/entity/P2823'), ('name', 'Royal Belgian Football Association player ID')]
# [('p', 'http://www.wikidata.org/entity/Q15944511'), ('name', 'association football team')]
# [('p', 'http://www.wikidata.org/entity/Q2736'), ('name', 'association football')]
# [('p', 'http://www.wikidata.org/entity/Q28640'), ('name', 'profession')]
# [('p', 'http://www.wikidata.org/entity/Q476028'), ('name', 'association football club')]
# [('p', 'http://www.wikidata.org/entity/Q31930761'), ('name', "men's association football")]
# [('p', 'http://www.wikidata.org/entity/Q17019799'), ('name', 'Template:SD Eibar squad')]
# [('p', 'http://www.wikidata.org/entity/Q2066131'), ('name', 'athlete')]
# [('p', 'http://www.wikidata.org/entity/Q606060'), ('name', "women's association football")]
# [('p', 'http://www.wikidata.org/entity/P1469'), ('name', 'FIFA player ID')]
# [('p', 'http://www.wikidata.org/entity/P4019'), ('name', 'USL Championship player ID')]
# [('p', 'http://www.wikidata.org/entity/P2574'), ('name', 'National-Football-Teams.com player ID')]
# [('p', 'http://www.wikidata.org/entity/Q6690764'), ('name', 'Template:Atlético Madrid squad')]
# [('p', 'http://www.wikidata.org/entity/Q1381731'), ('name', 'kit')]
# [('p', 'http://www.wikidata.org/entity/P3677'), ('name', 'Wereld van Oranje player ID')]
# 20

# %% [markdown]
# Final query for this task

# %%
# write your final query
#Using Association Football 
#[('p', 'http://www.wikidata.org/entity/Q476028'), ('name', 'association football club')]
queryString = """
SELECT DISTINCT ?p ?name
WHERE {
   # bind something
   wd:Q476028 ?p ?obj.
   # get the label
   # ?p sc:name ?name.
}
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P1424'), ('name', "topic's main template")]
# [('p', 'http://www.wikidata.org/prop/direct/P1709'), ('name', 'equivalent class')]
# [('p', 'http://www.wikidata.org/prop/direct/P18'), ('name', 'image')]
# [('p', 'http://www.wikidata.org/prop/direct/P1889'), ('name', 'different from')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('name', 'properties for this type')]
# [('p', 'http://www.wikidata.org/prop/direct/P227'), ('name', 'GND ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2354'), ('name', 'has list')]
# [('p', 'http://www.wikidata.org/prop/direct/P244'), ('name', 'Library of Congress authority ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2671'), ('name', 'Google Knowledge Graph ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P268'), ('name', 'Bibliothèque nationale de France ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('name', 'subclass of')]
# [('p', 'http://www.wikidata.org/prop/direct/P3417'), ('name', 'Quora topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3553'), ('name', 'Zhihu topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P373'), ('name', 'Commons category')]
# [('p', 'http://www.wikidata.org/prop/direct/P508'), ('name', 'BNCF Thesaurus ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('name', 'has part')]
# [('p', 'http://www.wikidata.org/prop/direct/P5869'), ('name', 'model item')]
# [('p', 'http://www.wikidata.org/prop/direct/P641'), ('name', 'sport')]
# [('p', 'http://www.wikidata.org/prop/direct/P646'), ('name', 'Freebase ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6573'), ('name', 'Klexikon article ID')]
# 20

# %% [markdown]
# ## Task 3
# Identify the BGP for association football league

# %%
# Using Association Football ID from Task 2
#[('p', 'http://www.wikidata.org/entity/Q2736'), ('name', 'association football')]
queryString = """
SELECT DISTINCT ?p ?name
WHERE {
   # bind something
   # ?p ?obj wd:Q2736.
   # get the label
   # ?p sc:name ?name.
   FILTER(REGEX(?name,"league"^^xsd:string))
}
LIMIT 200
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/entity/Q953425'), ('name', 'Italian association football league system')]
# [('p', 'http://www.wikidata.org/entity/Q1324755'), ('name', 'Argentine football league system')]
# [('p', 'http://www.wikidata.org/entity/Q20949773'), ('name', 'Zamalek SC league record by opponent')]
# [('p', 'http://www.wikidata.org/entity/Q20984260'), ('name', 'Vietnamese football league system')]
# [('p', 'http://www.wikidata.org/entity/Q24238546'), ('name', '2016–17 Football Superleague of Kosovo')]
# [('p', 'http://www.wikidata.org/entity/Q1824674'), ('name', 'league cup')]
# [('p', 'http://www.wikidata.org/entity/Q178544'), ('name', 'Swedish football league system')]
# [('p', 'http://www.wikidata.org/entity/Q835610'), ('name', 'German football league system')]
# [('p', 'http://www.wikidata.org/entity/Q3500681'), ('name', 'Norwegian football league system')]
# [('p', 'http://www.wikidata.org/entity/Q2186316'), ('name', 'Belgian Provincial leagues')]
# [('p', 'http://www.wikidata.org/entity/Q5161295'), ('name', 'Connacht senior league challenge cup')]
# [('p', 'http://www.wikidata.org/entity/Q5869451'), ('name', 'history of the German football league system')]
# [('p', 'http://www.wikidata.org/entity/Q10566836'), ('name', 'Hong Kong football league system')]
# [('p', 'http://www.wikidata.org/entity/Q1148179'), ('name', 'French football league system')]
# [('p', 'http://www.wikidata.org/entity/Q15991303'), ('name', 'association football league')]
# [('p', 'http://www.wikidata.org/entity/Q20648080'), ('name', '2015–16 Superleague Greece')]
# [('p', 'http://www.wikidata.org/entity/Q24908639'), ('name', "Indian women's football league")]
# [('p', 'http://www.wikidata.org/entity/Q954813'), ('name', 'Swiss football league system')]
# [('p', 'http://www.wikidata.org/entity/Q990558'), ('name', '2012–13 Superleague Greece')]
# [('p', 'http://www.wikidata.org/entity/Q1076448'), ('name', 'Turkish football league system')]
# [('p', 'http://www.wikidata.org/entity/Q1479242'), ('name', 'list of top goalscorers in Superleague Greece by season')]
# [('p', 'http://www.wikidata.org/entity/Q26897352'), ('name', 'football league season')]
# [('p', 'http://www.wikidata.org/entity/Q2744597'), ('name', 'Icelandic football league system')]
# [('p', 'http://www.wikidata.org/entity/Q6738076'), ('name', 'Template:CONMEBOL second leagues')]
# [('p', 'http://www.wikidata.org/entity/Q2252666'), ('name', 'Japanese association football league system')]
# [('p', 'http://www.wikidata.org/entity/Q4421004'), ('name', 'Northern Ireland football league system')]
# [('p', 'http://www.wikidata.org/entity/Q9350532'), ('name', 'The football league in Sweden')]
# [('p', 'http://www.wikidata.org/entity/Q16820681'), ('name', 'Sydney FC league record by opponent')]
# [('p', 'http://www.wikidata.org/entity/Q16843604'), ('name', 'list of Egyptian football players in foreign leagues')]
# [('p', 'http://www.wikidata.org/entity/Q1476483'), ('name', 'Thai football league system')]
# [('p', 'http://www.wikidata.org/entity/Q4628344'), ('name', '2012–13 Midlands football leagues')]
# [('p', 'http://www.wikidata.org/entity/Q4628435'), ('name', '2012–13 North Superleague')]
# [('p', 'http://www.wikidata.org/entity/Q978160'), ('name', 'Football Superleague of Kosovo')]
# [('p', 'http://www.wikidata.org/entity/Q1068104'), ('name', 'Mexican football league system')]
# [('p', 'http://www.wikidata.org/entity/Q6636237'), ('name', 'list of regional football leagues in Argentina')]
# [('p', 'http://www.wikidata.org/entity/Q18559'), ('name', 'English football league system')]
# [('p', 'http://www.wikidata.org/entity/Q12883787'), ('name', 'Superleague Greece Youth Leagues')]
# [('p', 'http://www.wikidata.org/entity/Q13408414'), ('name', 'Template:UEFA third level leagues')]
# [('p', 'http://www.wikidata.org/entity/Q6445216'), ('name', 'Template:Infobox football league season')]
# [('p', 'http://www.wikidata.org/entity/Q15306073'), ('name', 'Canadian soccer league system')]
# [('p', 'http://www.wikidata.org/entity/Q15410404'), ('name', '1942–43 Slovak league')]
# [('p', 'http://www.wikidata.org/entity/Q16725990'), ('name', 'Indonesian football league system')]
# [('p', 'http://www.wikidata.org/entity/Q17514914'), ('name', '2014–15 East Superleague')]
# [('p', 'http://www.wikidata.org/entity/Q17515346'), ('name', '2014–15 North Superleague')]
# [('p', 'http://www.wikidata.org/entity/Q25110997'), ('name', 'list of Salvadoran league top scorers')]
# [('p', 'http://www.wikidata.org/entity/Q10505457'), ('name', 'Template:AFC leagues')]
# [('p', 'http://www.wikidata.org/entity/Q10694828'), ('name', 'Template:OFC leagues')]
# [('p', 'http://www.wikidata.org/entity/Q24189140'), ('name', 'Central Coast Mariners FC league record by opponent')]
# [('p', 'http://www.wikidata.org/entity/Q6913128'), ('name', 'Moroccan football league system')]
# [('p', 'http://www.wikidata.org/entity/Q4724093'), ('name', 'Algerian football league system')]
# [('p', 'http://www.wikidata.org/entity/Q3187599'), ('name', 'Dutch football league system')]
# [('p', 'http://www.wikidata.org/entity/Q5187183'), ('name', 'Croatian football league system')]
# [('p', 'http://www.wikidata.org/entity/Q12618799'), ('name', '2013 challengers league')]
# [('p', 'http://www.wikidata.org/entity/Q25036433'), ('name', 'Steaua București league record by opponent')]
# [('p', 'http://www.wikidata.org/entity/Q18344502'), ('name', 'Gilan Province league')]
# [('p', 'http://www.wikidata.org/entity/Q64268674'), ('name', '2019–20 Superleague Greece')]
# [('p', 'http://www.wikidata.org/entity/Q4273927'), ('name', 'Finnish football league system')]
# [('p', 'http://www.wikidata.org/entity/Q6738006'), ('name', 'Template:CONCACAF second leagues')]
# [('p', 'http://www.wikidata.org/entity/Q6738094'), ('name', "Template:CONMEBOL women's leagues")]
# [('p', 'http://www.wikidata.org/entity/Q17332510'), ('name', 'Colchester United F.C. league record by opponent')]
# [('p', 'http://www.wikidata.org/entity/Q1756712'), ('name', 'Portuguese football league system')]
# [('p', 'http://www.wikidata.org/entity/Q8055390'), ('name', 'York City F.C. league record by opponent')]
# [('p', 'http://www.wikidata.org/entity/Q249275'), ('name', 'Ecuadorian football league system')]
# [('p', 'http://www.wikidata.org/entity/Q7567726'), ('name', 'South Korean football league system')]
# [('p', 'http://www.wikidata.org/entity/Q64424215'), ('name', '2019–20 Football Superleague of Kosovo')]
# [('p', 'http://www.wikidata.org/entity/Q97889551'), ('name', '2020–21 Football Superleague of Kosovo')]
# [('p', 'http://www.wikidata.org/entity/Q15811005'), ('name', 'Oberliga Nord football league, 1999/2000 season')]
# [('p', 'http://www.wikidata.org/entity/Q20331019'), ('name', 'Template:Campeonato de Portugal (league) seasons')]
# [('p', 'http://www.wikidata.org/entity/Q30217526'), ('name', '2017–18 Football Superleague of Kosovo')]
# [('p', 'http://www.wikidata.org/entity/Q2914'), ('name', 'Spanish football league system')]
# [('p', 'http://www.wikidata.org/entity/Q1968684'), ('name', '2011–12 Superleague Greece')]
# [('p', 'http://www.wikidata.org/entity/Q3653714'), ('name', 'Colombian football league system')]
# [('p', 'http://www.wikidata.org/entity/Q4916655'), ('name', 'Birmingham City F.C. league record by opponent')]
# [('p', 'http://www.wikidata.org/entity/Q8084309'), ('name', 'template:UEFA leagues')]
# [('p', 'http://www.wikidata.org/entity/Q3654091'), ('name', 'Israeli football league system')]
# [('p', 'http://www.wikidata.org/entity/Q7919843'), ('name', 'Venezuelan football league system')]
# [('p', 'http://www.wikidata.org/entity/Q1053629'), ('name', 'Belgian football league system')]
# [('p', 'http://www.wikidata.org/entity/Q3240336'), ('name', 'Football league of Burgundy')]
# [('p', 'http://www.wikidata.org/entity/Q2127556'), ('name', '2007–08 Football Superleague of Kosovo')]
# [('p', 'http://www.wikidata.org/entity/Q3654446'), ('name', 'Peruvian football league system')]
# [('p', 'http://www.wikidata.org/entity/Q2608516'), ('name', '2006–07 Superleague Greece')]
# [('p', 'http://www.wikidata.org/entity/Q4649108'), ('name', 'A2 volleyball league')]
# [('p', 'http://www.wikidata.org/entity/Q4820750'), ('name', 'Cypriot football league system')]
# [('p', 'http://www.wikidata.org/entity/Q4996250'), ('name', 'Bulgarian football league system')]
# [('p', 'http://www.wikidata.org/entity/Q5328421'), ('name', 'East German football league system')]
# [('p', 'http://www.wikidata.org/entity/Q6615926'), ('name', 'list of defunct football leagues in Scotland')]
# [('p', 'http://www.wikidata.org/entity/Q6630729'), ('name', 'list of non-league clubs in the Fifth Round of the FA Cup since 1945')]
# [('p', 'http://www.wikidata.org/entity/Q16835383'), ('name', '2013–14 North Superleague')]
# [('p', 'http://www.wikidata.org/entity/Q16847092'), ('name', 'Pakistan football league system')]
# [('p', 'http://www.wikidata.org/entity/Q30680897'), ('name', "list of Singapore's football leagues winners")]
# [('p', 'http://www.wikidata.org/entity/Q55606354'), ('name', 'CS Universitatea Craiova league record by opponent')]
# [('p', 'http://www.wikidata.org/entity/Q6658451'), ('name', 'Liverpool F.C. league record by opponent')]
# [('p', 'http://www.wikidata.org/entity/Q6664162'), ('name', "Template:AFC women's leagues")]
# [('p', 'http://www.wikidata.org/entity/Q6706271'), ('name', 'Luxembourg football league system')]
# [('p', 'http://www.wikidata.org/entity/Q1065655'), ('name', 'Uruguayan football league system')]
# [('p', 'http://www.wikidata.org/entity/Q1194166'), ('name', '2010–11 Superleague Greece')]
# [('p', 'http://www.wikidata.org/entity/Q3647167'), ('name', 'Greek football league system')]
# [('p', 'http://www.wikidata.org/entity/Q14387428'), ('name', 'Template:UEFA fourth level leagues')]
# [('p', 'http://www.wikidata.org/entity/Q22087208'), ('name', 'Preston North End F.C. league record by opponent')]
# [('p', 'http://www.wikidata.org/entity/Q5551885'), ('name', "German women's football league system")]
# [('p', 'http://www.wikidata.org/entity/Q16243107'), ('name', 'Arsenal F.C. league record by opponent')]
# [('p', 'http://www.wikidata.org/entity/Q20111028'), ('name', 'Kowsar Women Football league')]
# [('p', 'http://www.wikidata.org/entity/Q3083087'), ('name', 'Bosnian football league system')]
# [('p', 'http://www.wikidata.org/entity/Q1150384'), ('name', 'Chilean football league system')]
# [('p', 'http://www.wikidata.org/entity/Q63225540'), ('name', 'Lebanese football league system')]
# [('p', 'http://www.wikidata.org/entity/Q2567974'), ('name', 'Ukrainian football league system')]
# [('p', 'http://www.wikidata.org/entity/Q911940'), ('name', 'Russian football league system')]
# [('p', 'http://www.wikidata.org/entity/Q4615764'), ('name', '2009–10 Football Superleague of Kosovo')]
# [('p', 'http://www.wikidata.org/entity/Q10727399'), ('name', 'Template:CONCACAF leagues')]
# [('p', 'http://www.wikidata.org/entity/Q15410401'), ('name', '1939–40 Slovak league')]
# [('p', 'http://www.wikidata.org/entity/Q11160363'), ('name', 'Template:CAF leagues')]
# [('p', 'http://www.wikidata.org/entity/Q18389049'), ('name', 'East Azerbaijan Province league')]
# [('p', 'http://www.wikidata.org/entity/Q2951970'), ('name', '1999 New Zealand island soccer leagues')]
# [('p', 'http://www.wikidata.org/entity/Q5610928'), ('name', 'Ground developments to football stadiums in the English football league system')]
# [('p', 'http://www.wikidata.org/entity/Q20806459'), ('name', 'Inter-country league Rijeka')]
# [('p', 'http://www.wikidata.org/entity/Q48995939'), ('name', 'list of association football clubs playing in the league of another country')]
# [('p', 'http://www.wikidata.org/entity/Q54085113'), ('name', '2018–19 Superleague Greece')]
# [('p', 'http://www.wikidata.org/entity/Q28448349'), ('name', 'Futsal Superleague of Kosovo')]
# [('p', 'http://www.wikidata.org/entity/Q28453823'), ('name', 'Celtic F.C. league record by opponent')]
# [('p', 'http://www.wikidata.org/entity/Q48836284'), ('name', 'IFK Göteborg league record by opponent')]
# [('p', 'http://www.wikidata.org/entity/Q55098812'), ('name', 'Southampton F.C. league record by opponent')]
# [('p', 'http://www.wikidata.org/entity/Q24900599'), ('name', '2016–17 East Superleague')]
# [('p', 'http://www.wikidata.org/entity/Q29962267'), ('name', 'Superleague Soccer')]
# [('p', 'http://www.wikidata.org/entity/Q21187805'), ('name', '2015–16 Football Superleague of Kosovo')]
# [('p', 'http://www.wikidata.org/entity/Q39053182'), ('name', '2017–18 East Superleague')]
# [('p', 'http://www.wikidata.org/entity/Q16850570'), ('name', 'Soviet Union football league system')]
# [('p', 'http://www.wikidata.org/entity/Q55388738'), ('name', '2018–19 East Superleague')]
# [('p', 'http://www.wikidata.org/entity/Q15410403'), ('name', '1941–42 Slovak league')]
# [('p', 'http://www.wikidata.org/entity/Q16851149'), ('name', '2014–15 Superleague Greece')]
# [('p', 'http://www.wikidata.org/entity/Q25036426'), ('name', 'Djurgårdens IF Fotboll league record by opponent')]
# [('p', 'http://www.wikidata.org/entity/Q30125744'), ('name', '2017–18 Superleague Greece')]
# [('p', 'http://www.wikidata.org/entity/Q4873678'), ('name', 'Bavarian football league system')]
# [('p', 'http://www.wikidata.org/entity/Q16151523'), ('name', 'Qatar football league system')]
# [('p', 'http://www.wikidata.org/entity/Q1050077'), ('name', '2008–09 Superleague Greece')]
# [('p', 'http://www.wikidata.org/entity/Q923671'), ('name', '2009–10 Superleague Greece')]
# [('p', 'http://www.wikidata.org/entity/Q12872818'), ('name', 'Athens F.C.A. A league')]
# [('p', 'http://www.wikidata.org/entity/Q6664030'), ('name', 'Template:AFC second leagues')]
# [('p', 'http://www.wikidata.org/entity/Q7314474'), ('name', 'Republic of Ireland football league system')]
# [('p', 'http://www.wikidata.org/entity/Q6744416'), ('name', 'Malmö FF league record by opponent')]
# [('p', 'http://www.wikidata.org/entity/Q22098118'), ('name', '2015–16 East Superleague')]
# [('p', 'http://www.wikidata.org/entity/Q24993252'), ('name', 'Isle of Man football league system')]
# [('p', 'http://www.wikidata.org/entity/Q48817172'), ('name', "list of FA and league honours won by men's clubs")]
# [('p', 'http://www.wikidata.org/entity/Q2249739'), ('name', 'Czech Republic football league system')]
# [('p', 'http://www.wikidata.org/entity/Q3654445'), ('name', 'Paraguayan football league system')]
# [('p', 'http://www.wikidata.org/entity/Q25168658'), ('name', '2016–17 North Superleague')]
# [('p', 'http://www.wikidata.org/entity/Q932449'), ('name', 'list of association football clubs playing in the league of another country')]
# [('p', 'http://www.wikidata.org/entity/Q6045087'), ('name', 'Inter Milan league record by opponent')]
# [('p', 'http://www.wikidata.org/entity/Q6564533'), ('name', 'list of Bradford City A.F.C. players with fewer than 50 league appearances')]
# [('p', 'http://www.wikidata.org/entity/Q6620632'), ('name', 'list of football clubs in Denmark by league')]
# [('p', 'http://www.wikidata.org/entity/Q20712116'), ('name', 'Milton Keynes Dons F.C. league record by opponent')]
# [('p', 'http://www.wikidata.org/entity/Q4832425'), ('name', 'Azerbaijani football league system')]
# [('p', 'http://www.wikidata.org/entity/Q55636313'), ('name', 'Turkish Cypriot football league system')]
# [('p', 'http://www.wikidata.org/entity/Q18203444'), ('name', '2nd Czechoslovak football league')]
# [('p', 'http://www.wikidata.org/entity/Q53866634'), ('name', '2018–19 Football Superleague of Kosovo')]
# [('p', 'http://www.wikidata.org/entity/Q4939600'), ('name', 'Bolivian football league system')]
# [('p', 'http://www.wikidata.org/entity/Q5100790'), ('name', 'Chinese football league system')]
# [('p', 'http://www.wikidata.org/entity/Q6735270'), ('name', 'Template:CAF second leagues')]
# [('p', 'http://www.wikidata.org/entity/Q18126452'), ('name', 'AFC Wimbledon league record by opponent')]
# [('p', 'http://www.wikidata.org/entity/Q18027088'), ('name', '2014–15 Football Superleague of Kosovo')]
# [('p', 'http://www.wikidata.org/entity/Q55617544'), ('name', 'list of association football leagues without promotion and relegation')]
# [('p', 'http://www.wikidata.org/entity/Q847134'), ('name', 'Romanian association football league system')]
# [('p', 'http://www.wikidata.org/entity/Q2127539'), ('name', '2011–12 Football Superleague of Kosovo')]
# [('p', 'http://www.wikidata.org/entity/Q2127554'), ('name', '2008–09 Football Superleague of Kosovo')]
# [('p', 'http://www.wikidata.org/entity/Q1152339'), ('name', 'Brazilian football league system')]
# [('p', 'http://www.wikidata.org/entity/Q7452910'), ('name', 'Serbian football league system')]
# [('p', 'http://www.wikidata.org/entity/Q7644469'), ('name', 'Supplementary football leagues')]
# [('p', 'http://www.wikidata.org/entity/Q16225438'), ('name', 'list of foreign footballers in top leagues of former Yugoslavia')]
# [('p', 'http://www.wikidata.org/entity/Q16257851'), ('name', 'Manchester City F.C. league record by opponent')]
# [('p', 'http://www.wikidata.org/entity/Q16843120'), ('name', 'Melbourne Heart FC league record by opponent')]
# [('p', 'http://www.wikidata.org/entity/Q20712988'), ('name', 'Powerleague')]
# [('p', 'http://www.wikidata.org/entity/Q1054125'), ('name', 'United States soccer league system')]
# [('p', 'http://www.wikidata.org/entity/Q13413018'), ('name', 'Template:UEFA second leagues')]
# [('p', 'http://www.wikidata.org/entity/Q23719469'), ('name', '2016–17 Superleague Greece')]
# [('p', 'http://www.wikidata.org/entity/Q24298834'), ('name', 'Chelsea F.C. league record by opponent')]
# [('p', 'http://www.wikidata.org/entity/Q28454551'), ('name', 'list of Cape Verdean league top scorers')]
# [('p', 'http://www.wikidata.org/entity/Q18204956'), ('name', 'Kuwaiti futsal league')]
# [('p', 'http://www.wikidata.org/entity/Q15410405'), ('name', '1943–44 Slovak league')]
# [('p', 'http://www.wikidata.org/entity/Q27963742'), ('name', 'USM Alger league record by opponent')]
# [('p', 'http://www.wikidata.org/entity/Q469029'), ('name', 'Hungarian football league system')]
# [('p', 'http://www.wikidata.org/entity/Q5326837'), ('name', 'Early league football in Dumfries and Galloway')]
# [('p', 'http://www.wikidata.org/entity/Q5892952'), ('name', 'Honduran football league system')]
# [('p', 'http://www.wikidata.org/entity/Q7492770'), ('name', 'Sheffield United F.C. league record by opponent')]
# [('p', 'http://www.wikidata.org/entity/Q2127549'), ('name', '2012–13 Football Superleague of Kosovo')]
# [('p', 'http://www.wikidata.org/entity/Q2127547'), ('name', '2010–11 Football Superleague of Kosovo')]
# [('p', 'http://www.wikidata.org/entity/Q4553716'), ('name', '17th of Shahrivar league')]
# [('p', 'http://www.wikidata.org/entity/Q4619732'), ('name', '2010–11 North Superleague')]
# [('p', 'http://www.wikidata.org/entity/Q21627307'), ('name', 'Nigerian football league system')]
# [('p', 'http://www.wikidata.org/entity/Q2510524'), ('name', 'Scottish football league system')]
# [('p', 'http://www.wikidata.org/entity/Q6735290'), ('name', "Template:CAF women's leagues")]
# [('p', 'http://www.wikidata.org/entity/Q6738125'), ('name', 'Template:CONMEBOL leagues')]
# [('p', 'http://www.wikidata.org/entity/Q6744835'), ('name', 'Maltese football league system')]
# [('p', 'http://www.wikidata.org/entity/Q16843110'), ('name', 'Derby County F.C. league record by opponent')]
# [('p', 'http://www.wikidata.org/entity/Q16257847'), ('name', '2013–14 Midlands football leagues')]
# [('p', 'http://www.wikidata.org/entity/Q22098108'), ('name', '2015–16 North Superleague')]
# [('p', 'http://www.wikidata.org/entity/Q4627958'), ('name', '2012–13 East Superleague')]
# [('p', 'http://www.wikidata.org/entity/Q21061811'), ('name', 'Sunderland A.F.C. league record by opponent')]
# [('p', 'http://www.wikidata.org/entity/Q3240521'), ('name', 'Moroccan football league')]
# [('p', 'http://www.wikidata.org/entity/Q82899'), ('name', 'State football leagues in Brazil')]
# [('p', 'http://www.wikidata.org/entity/Q7639616'), ('name', 'Sunday league football')]
# [('p', 'http://www.wikidata.org/entity/Q29587195'), ('name', '2017-18 North Superleague')]
# 200

# %% [markdown]
# Final query for this task

# %%
# write your final query
#[('p', 'http://www.wikidata.org/entity/Q15991303'), ('name', 'association football league')]
queryString = """
SELECT DISTINCT ?p ?name
WHERE {
   # bind something
     wd:Q15991303 ?p ?o.
   # get the label
   # ?p sc:name ?name.
}
LIMIT 200
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P1424'), ('name', "topic's main template")]
# [('p', 'http://www.wikidata.org/prop/direct/P1709'), ('name', 'equivalent class')]
# [('p', 'http://www.wikidata.org/prop/direct/P1889'), ('name', 'different from')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('name', 'properties for this type')]
# [('p', 'http://www.wikidata.org/prop/direct/P2671'), ('name', 'Google Knowledge Graph ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('name', 'subclass of')]
# [('p', 'http://www.wikidata.org/prop/direct/P641'), ('name', 'sport')]
# [('p', 'http://www.wikidata.org/prop/direct/P8408'), ('name', 'KBpedia ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P910'), ('name', "topic's main category")]
# 9

# %% [markdown]
# ## Task 4
# Return for each european country the number of association football leagues (the result set must be a list of triples country IRI, label and #leagues).

# %%
# write your queries
#Using Association Foorball Leagues for searching
queryString = """
SELECT DISTINCT ?p ?name ?oname ?obj
WHERE {
   # bind something
   wd:Q15991303 ?obj ?p.
   # get the label
   # ?p sc:name ?name.
   # ?obj sc:name ?oname.
}
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/entity/Q8085406'), ('name', 'Template:Infobox football league'), ('oname', "topic's main template"), ('obj', 'http://www.wikidata.org/prop/direct/P1424')]
# [('p', 'http://www.wikidata.org/entity/Q26887310'), ('name', 'association football team season'), ('oname', 'different from'), ('obj', 'http://www.wikidata.org/prop/direct/P1889')]
# [('p', 'http://www.wikidata.org/entity/P1132'), ('name', 'number of participants'), ('oname', 'properties for this type'), ('obj', 'http://www.wikidata.org/prop/direct/P1963')]
# [('p', 'http://www.wikidata.org/entity/P2500'), ('name', 'league level below'), ('oname', 'properties for this type'), ('obj', 'http://www.wikidata.org/prop/direct/P1963')]
# [('p', 'http://www.wikidata.org/entity/P6118'), ('name', 'season ends'), ('oname', 'properties for this type'), ('obj', 'http://www.wikidata.org/prop/direct/P1963')]
# [('p', 'http://www.wikidata.org/entity/P3195'), ('name', 'league points system'), ('oname', 'properties for this type'), ('obj', 'http://www.wikidata.org/prop/direct/P1963')]
# [('p', 'http://www.wikidata.org/entity/P641'), ('name', 'sport'), ('oname', 'properties for this type'), ('obj', 'http://www.wikidata.org/prop/direct/P1963')]
# [('p', 'http://www.wikidata.org/entity/P2499'), ('name', 'league level above'), ('oname', 'properties for this type'), ('obj', 'http://www.wikidata.org/prop/direct/P1963')]
# [('p', 'http://www.wikidata.org/entity/P4794'), ('name', 'season starts'), ('oname', 'properties for this type'), ('obj', 'http://www.wikidata.org/prop/direct/P1963')]
# [('p', 'http://www.wikidata.org/entity/P17'), ('name', 'country'), ('oname', 'properties for this type'), ('obj', 'http://www.wikidata.org/prop/direct/P1963')]
# [('p', 'http://www.wikidata.org/entity/P3822'), ('name', 'rules for classification'), ('oname', 'properties for this type'), ('obj', 'http://www.wikidata.org/prop/direct/P1963')]
# [('p', 'http://www.wikidata.org/entity/P3983'), ('name', 'sports league level'), ('oname', 'properties for this type'), ('obj', 'http://www.wikidata.org/prop/direct/P1963')]
# [('p', 'http://www.wikidata.org/entity/P664'), ('name', 'organizer'), ('oname', 'properties for this type'), ('obj', 'http://www.wikidata.org/prop/direct/P1963')]
# [('p', 'http://www.wikidata.org/entity/Q1478437'), ('name', 'association football competition'), ('oname', 'subclass of'), ('obj', 'http://www.wikidata.org/prop/direct/P279')]
# [('p', 'http://www.wikidata.org/entity/Q623109'), ('name', 'sports league'), ('oname', 'subclass of'), ('obj', 'http://www.wikidata.org/prop/direct/P279')]
# [('p', 'http://www.wikidata.org/entity/Q2736'), ('name', 'association football'), ('oname', 'sport'), ('obj', 'http://www.wikidata.org/prop/direct/P641')]
# [('p', 'http://www.wikidata.org/entity/Q6383739'), ('name', 'Category:Association football leagues'), ('oname', "topic's main category"), ('obj', 'http://www.wikidata.org/prop/direct/P910')]
# 17

# %%
# write your queries
#Using Association Foorball Leagues for searching
queryString = """
SELECT DISTINCT ?p ?name ?oname ?obj
WHERE {
   # bind something
    # ?obj ?p wd:Q15991303.
   # get the label
   # ?p sc:name ?name.
   # ?obj sc:name ?oname.
}
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P971'), ('name', 'category combines topics'), ('oname', 'Category:1994 in Swedish association football leagues'), ('obj', 'http://www.wikidata.org/entity/Q8175816')]
# [('p', 'http://www.wikidata.org/prop/direct/P971'), ('name', 'category combines topics'), ('oname', 'Category:2000 in Swedish association football leagues'), ('obj', 'http://www.wikidata.org/entity/Q8182829')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('name', 'instance of'), ('oname', 'Uzbekistan Pro League'), ('obj', 'http://www.wikidata.org/entity/Q304228')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('name', 'instance of'), ('oname', 'Ligue 2'), ('obj', 'http://www.wikidata.org/entity/Q2950655')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('name', 'instance of'), ('oname', "Moldovan women's football championship"), ('obj', 'http://www.wikidata.org/entity/Q2951924')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('name', 'instance of'), ('oname', 'Championnat National 3'), ('obj', 'http://www.wikidata.org/entity/Q973312')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('name', 'instance of'), ('oname', '3. divisjon'), ('obj', 'http://www.wikidata.org/entity/Q2792041')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('name', 'instance of'), ('oname', 'Nemzeti Bajnokság III'), ('obj', 'http://www.wikidata.org/entity/Q1162407')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('name', 'instance of'), ('oname', 'Landesliga Niederrhein'), ('obj', 'http://www.wikidata.org/entity/Q1476473')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('name', 'instance of'), ('oname', 'Russian Football National League Competition'), ('obj', 'http://www.wikidata.org/entity/Q162533')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('name', 'instance of'), ('oname', 'Liga III'), ('obj', 'http://www.wikidata.org/entity/Q1707697')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('name', 'instance of'), ('oname', 'A-League'), ('obj', 'http://www.wikidata.org/entity/Q219586')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('name', 'instance of'), ('oname', 'Slovak Super Liga'), ('obj', 'http://www.wikidata.org/entity/Q238113')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('name', 'instance of'), ('oname', 'Bremen-Liga'), ('obj', 'http://www.wikidata.org/entity/Q475887')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('name', 'instance of'), ('oname', 'Segona Divisió'), ('obj', 'http://www.wikidata.org/entity/Q541065')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('name', 'instance of'), ('oname', 'Ýokary Liga'), ('obj', 'http://www.wikidata.org/entity/Q1090867')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('name', 'instance of'), ('oname', 'Scottish Football League Second Division'), ('obj', 'http://www.wikidata.org/entity/Q1473324')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('name', 'instance of'), ('oname', 'Serbian First League'), ('obj', 'http://www.wikidata.org/entity/Q1813595')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('name', 'instance of'), ('oname', 'Ligue de la Méditerranée de football'), ('obj', 'http://www.wikidata.org/entity/Q3240443')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('name', 'instance of'), ('oname', 'Primera División Femenina'), ('obj', 'http://www.wikidata.org/entity/Q40068')]
# 20

# %%
#Usign single FootBall League for BGP and checking the country connection
queryString = """
SELECT DISTINCT ?p ?name ?oname ?obj
WHERE {
   # bind something
    wd:Q3240443 ?obj ?p .
   # get the label
   # ?p sc:name ?name.
   # ?obj sc:name ?oname.
}
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/entity/Q142'), ('name', 'France'), ('oname', 'country'), ('obj', 'http://www.wikidata.org/prop/direct/P17')]
# [('p', 'http://www.wikidata.org/entity/Q15991303'), ('name', 'association football league'), ('oname', 'instance of'), ('obj', 'http://www.wikidata.org/prop/direct/P31')]
# [('p', 'http://www.wikidata.org/entity/Q2736'), ('name', 'association football'), ('oname', 'sport'), ('obj', 'http://www.wikidata.org/prop/direct/P641')]
# 3

# %%
# Using Country ID for exploring
#[('p', 'http://www.wikidata.org/entity/P17'), ('name', 'country')]
queryString = """
SELECT DISTINCT ?p ?name
WHERE {
   # bind something
   # ?p wdt:P17 ?p.
   # get the label
   # ?p sc:name ?name.
   FILTER(REGEX(?name,"Italy"^^xsd:string))
}
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/entity/Q223936'), ('name', 'Kingdom of Italy')]
# [('p', 'http://www.wikidata.org/entity/Q172579'), ('name', 'Kingdom of Italy')]
# [('p', 'http://www.wikidata.org/entity/Q38'), ('name', 'Italy')]
# [('p', 'http://www.wikidata.org/entity/Q5343710'), ('name', 'Kingdom of Italy')]
# 4

# %%
# Using specific country for exploring
#[('p', 'http://www.wikidata.org/entity/P17'), ('name', 'country')]
#[('p', 'http://www.wikidata.org/entity/Q38'), ('name', 'Italy')]
queryString = """
SELECT DISTINCT ?p ?name
WHERE {
   # bind something
   wd:Q38 ?p ?obj.
   # get the label
   # ?p sc:name ?name.

}
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P1005'), ('name', 'Portuguese National Library ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1036'), ('name', 'Dewey Decimal Classification')]
# [('p', 'http://www.wikidata.org/prop/direct/P1081'), ('name', 'Human Development Index')]
# [('p', 'http://www.wikidata.org/prop/direct/P1082'), ('name', 'population')]
# [('p', 'http://www.wikidata.org/prop/direct/P1120'), ('name', 'number of deaths')]
# [('p', 'http://www.wikidata.org/prop/direct/P1151'), ('name', "topic's main Wikimedia portal")]
# [('p', 'http://www.wikidata.org/prop/direct/P1198'), ('name', 'unemployment rate')]
# [('p', 'http://www.wikidata.org/prop/direct/P122'), ('name', 'basic form of government')]
# [('p', 'http://www.wikidata.org/prop/direct/P1225'), ('name', 'U.S. National Archives Identifier')]
# [('p', 'http://www.wikidata.org/prop/direct/P1245'), ('name', 'OmegaWiki Defined Meaning')]
# [('p', 'http://www.wikidata.org/prop/direct/P1296'), ('name', 'Gran Enciclopèdia Catalana ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1313'), ('name', 'office held by head of government')]
# [('p', 'http://www.wikidata.org/prop/direct/P1343'), ('name', 'described by source')]
# [('p', 'http://www.wikidata.org/prop/direct/P1365'), ('name', 'replaces')]
# [('p', 'http://www.wikidata.org/prop/direct/P1417'), ('name', 'Encyclopædia Britannica Online ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1419'), ('name', 'shape')]
# [('p', 'http://www.wikidata.org/prop/direct/P1438'), ('name', 'Jewish Encyclopedia ID (Russian)')]
# [('p', 'http://www.wikidata.org/prop/direct/P1451'), ('name', 'motto text')]
# [('p', 'http://www.wikidata.org/prop/direct/P1464'), ('name', 'category for people born here')]
# [('p', 'http://www.wikidata.org/prop/direct/P1465'), ('name', 'category for people who died here')]
# 20

# %%
# Using continent for exploring
#[('p', 'http://www.wikidata.org/entity/P17'), ('name', 'country')]
#[('p', 'http://www.wikidata.org/entity/Q38'), ('name', 'Italy')]
#[('p', 'http://www.wikidata.org/prop/direct/P30'), ('name', 'continent')]
queryString = """
SELECT DISTINCT ?p ?name
WHERE {
   # bind something
   # ?obj wdt:P30 ?p.
   # get the label
   # ?p sc:name ?name.
   #FILTER(REGEX(?name,"Italy"^^xsd:string))
}
LIMIT 200
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/entity/Q60140'), ('name', 'Indian subcontinent')]
# [('p', 'http://www.wikidata.org/entity/Q55643'), ('name', 'Oceania')]
# [('p', 'http://www.wikidata.org/entity/Q19464773'), ('name', 'Northern America and Mexico')]
# [('p', 'http://www.wikidata.org/entity/Q1239'), ('name', 'Indian Ocean')]
# [('p', 'http://www.wikidata.org/entity/Q15'), ('name', 'Africa')]
# [('p', 'http://www.wikidata.org/entity/Q18'), ('name', 'South America')]
# [('p', 'http://www.wikidata.org/entity/Q4412'), ('name', 'West Africa')]
# [('p', 'http://www.wikidata.org/entity/Q46'), ('name', 'Europe')]
# [('p', 'http://www.wikidata.org/entity/Q48'), ('name', 'Asia')]
# [('p', 'http://www.wikidata.org/entity/Q49'), ('name', 'North America')]
# [('p', 'http://www.wikidata.org/entity/Q51'), ('name', 'Antarctica')]
# [('p', 'http://www.wikidata.org/entity/Q538'), ('name', 'Insular Oceania')]
# [('p', 'http://www.wikidata.org/entity/Q5401'), ('name', 'Eurasia')]
# [('p', 'http://www.wikidata.org/entity/Q620634'), ('name', 'Bir Tawil')]
# [('p', 'http://www.wikidata.org/entity/Q664609'), ('name', 'Caribbean')]
# [('p', 'http://www.wikidata.org/entity/Q97'), ('name', 'Atlantic Ocean')]
# [('p', 'http://www.wikidata.org/entity/Q98'), ('name', 'Pacific Ocean')]
# [('p', 'http://www.wikidata.org/entity/Q828'), ('name', 'Americas')]
# [('p', 'http://www.wikidata.org/entity/Q27611'), ('name', 'Central America')]
# [('p', 'http://www.wikidata.org/entity/Q3960'), ('name', 'Australia')]
# [('p', 'http://www.wikidata.org/entity/Q243333'), ('name', 'Hyperborea')]
# [('p', 'http://www.wikidata.org/entity/Q107665732'), ('name', 'Hyboria')]
# [('p', 'http://www.wikidata.org/entity/Q2622787'), ('name', 'Faerûn')]
# [('p', 'http://www.wikidata.org/entity/Q3143'), ('name', 'Europa')]
# [('p', 'http://www.wikidata.org/entity/Q726891'), ('name', 'Asia')]
# [('p', 'http://www.wikidata.org/entity/Q29876'), ('name', 'Middle America')]
# [('p', 'http://www.wikidata.org/entity/Q3623561'), ('name', 'Westeros')]
# [('p', 'http://www.wikidata.org/entity/Q10944852'), ('name', 'Essos')]
# [('p', 'http://www.wikidata.org/entity/Q107616725'), ('name', 'Alfrey')]
# [('p', 'http://www.wikidata.org/entity/Q108151247'), ('name', 'Thuria')]
# [('p', 'http://www.wikidata.org/entity/Q230634'), ('name', 'Asia')]
# [('p', 'http://www.wikidata.org/entity/Q108572150'), ('name', 'The Continent')]
# [('p', 'http://www.wikidata.org/entity/Q3192885'), ('name', 'Kara-Tur')]
# 33

# %%
#Using Europe to find all countries 
#[('p', 'http://www.wikidata.org/entity/Q46'), ('name', 'Europe')]
queryString = """
SELECT DISTINCT ?p ?name
WHERE {
   # bind something
     wd:Q46 wdt:P527 ?p.
   # get the label
   # ?p sc:name ?name.
   #FILTER(REGEX(?name,"Italy"^^xsd:string))
}
LIMIT 200
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/entity/Q263686'), ('name', 'Southeast Europe')]
# [('p', 'http://www.wikidata.org/entity/Q27468'), ('name', 'Eastern Europe')]
# [('p', 'http://www.wikidata.org/entity/Q27496'), ('name', 'Western Europe')]
# [('p', 'http://www.wikidata.org/entity/Q27509'), ('name', 'Central Europe')]
# [('p', 'http://www.wikidata.org/entity/Q50807777'), ('name', 'Southwestern Europe')]
# [('p', 'http://www.wikidata.org/entity/Q27449'), ('name', 'Southern Europe')]
# [('p', 'http://www.wikidata.org/entity/Q27479'), ('name', 'Northern Europe')]
# [('p', 'http://www.wikidata.org/entity/Q1998497'), ('name', 'North Eastern Europe')]
# [('p', 'http://www.wikidata.org/entity/Q1414323'), ('name', 'Northwestern Europe')]
# 9

# %%
#Using Europe to find all countries 
#[('p', 'http://www.wikidata.org/entity/Q46'), ('name', 'Europe')]
queryString = """
SELECT DISTINCT ?p ?name ?cname ?m
WHERE {
   # bind something
     wd:Q46 wdt:P527 ?p.
     # ?p wdt:P527 ?cname.
     
   # get the label
   # ?p sc:name ?name.
   # ?cname sc:name ?m.
}
LIMIT 200
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/entity/Q27449'), ('name', 'Southern Europe'), ('cname', 'http://www.wikidata.org/entity/Q1410'), ('m', 'Gibraltar')]
# [('p', 'http://www.wikidata.org/entity/Q27496'), ('name', 'Western Europe'), ('cname', 'http://www.wikidata.org/entity/Q142'), ('m', 'France')]
# [('p', 'http://www.wikidata.org/entity/Q27509'), ('name', 'Central Europe'), ('cname', 'http://www.wikidata.org/entity/Q142'), ('m', 'France')]
# [('p', 'http://www.wikidata.org/entity/Q27509'), ('name', 'Central Europe'), ('cname', 'http://www.wikidata.org/entity/Q145'), ('m', 'United Kingdom')]
# [('p', 'http://www.wikidata.org/entity/Q27479'), ('name', 'Northern Europe'), ('cname', 'http://www.wikidata.org/entity/Q145'), ('m', 'United Kingdom')]
# [('p', 'http://www.wikidata.org/entity/Q27496'), ('name', 'Western Europe'), ('cname', 'http://www.wikidata.org/entity/Q183'), ('m', 'Germany')]
# [('p', 'http://www.wikidata.org/entity/Q27509'), ('name', 'Central Europe'), ('cname', 'http://www.wikidata.org/entity/Q183'), ('m', 'Germany')]
# [('p', 'http://www.wikidata.org/entity/Q27468'), ('name', 'Eastern Europe'), ('cname', 'http://www.wikidata.org/entity/Q184'), ('m', 'Belarus')]
# [('p', 'http://www.wikidata.org/entity/Q27479'), ('name', 'Northern Europe'), ('cname', 'http://www.wikidata.org/entity/Q189'), ('m', 'Iceland')]
# [('p', 'http://www.wikidata.org/entity/Q27479'), ('name', 'Northern Europe'), ('cname', 'http://www.wikidata.org/entity/Q191'), ('m', 'Estonia')]
# [('p', 'http://www.wikidata.org/entity/Q27479'), ('name', 'Northern Europe'), ('cname', 'http://www.wikidata.org/entity/Q20'), ('m', 'Norway')]
# [('p', 'http://www.wikidata.org/entity/Q27479'), ('name', 'Northern Europe'), ('cname', 'http://www.wikidata.org/entity/Q211'), ('m', 'Latvia')]
# [('p', 'http://www.wikidata.org/entity/Q27468'), ('name', 'Eastern Europe'), ('cname', 'http://www.wikidata.org/entity/Q212'), ('m', 'Ukraine')]
# [('p', 'http://www.wikidata.org/entity/Q27468'), ('name', 'Eastern Europe'), ('cname', 'http://www.wikidata.org/entity/Q213'), ('m', 'Czech Republic')]
# [('p', 'http://www.wikidata.org/entity/Q27509'), ('name', 'Central Europe'), ('cname', 'http://www.wikidata.org/entity/Q213'), ('m', 'Czech Republic')]
# [('p', 'http://www.wikidata.org/entity/Q27468'), ('name', 'Eastern Europe'), ('cname', 'http://www.wikidata.org/entity/Q214'), ('m', 'Slovakia')]
# [('p', 'http://www.wikidata.org/entity/Q27509'), ('name', 'Central Europe'), ('cname', 'http://www.wikidata.org/entity/Q214'), ('m', 'Slovakia')]
# [('p', 'http://www.wikidata.org/entity/Q27449'), ('name', 'Southern Europe'), ('cname', 'http://www.wikidata.org/entity/Q215'), ('m', 'Slovenia')]
# [('p', 'http://www.wikidata.org/entity/Q27468'), ('name', 'Eastern Europe'), ('cname', 'http://www.wikidata.org/entity/Q217'), ('m', 'Moldova')]
# [('p', 'http://www.wikidata.org/entity/Q27468'), ('name', 'Eastern Europe'), ('cname', 'http://www.wikidata.org/entity/Q218'), ('m', 'Romania')]
# [('p', 'http://www.wikidata.org/entity/Q27468'), ('name', 'Eastern Europe'), ('cname', 'http://www.wikidata.org/entity/Q219'), ('m', 'Bulgaria')]
# [('p', 'http://www.wikidata.org/entity/Q27449'), ('name', 'Southern Europe'), ('cname', 'http://www.wikidata.org/entity/Q221'), ('m', 'North Macedonia')]
# [('p', 'http://www.wikidata.org/entity/Q27449'), ('name', 'Southern Europe'), ('cname', 'http://www.wikidata.org/entity/Q222'), ('m', 'Albania')]
# [('p', 'http://www.wikidata.org/entity/Q27449'), ('name', 'Southern Europe'), ('cname', 'http://www.wikidata.org/entity/Q224'), ('m', 'Croatia')]
# [('p', 'http://www.wikidata.org/entity/Q27449'), ('name', 'Southern Europe'), ('cname', 'http://www.wikidata.org/entity/Q225'), ('m', 'Bosnia and Herzegovina')]
# [('p', 'http://www.wikidata.org/entity/Q27449'), ('name', 'Southern Europe'), ('cname', 'http://www.wikidata.org/entity/Q228'), ('m', 'Andorra')]
# [('p', 'http://www.wikidata.org/entity/Q27449'), ('name', 'Southern Europe'), ('cname', 'http://www.wikidata.org/entity/Q233'), ('m', 'Malta')]
# [('p', 'http://www.wikidata.org/entity/Q27496'), ('name', 'Western Europe'), ('cname', 'http://www.wikidata.org/entity/Q235'), ('m', 'Monaco')]
# [('p', 'http://www.wikidata.org/entity/Q27449'), ('name', 'Southern Europe'), ('cname', 'http://www.wikidata.org/entity/Q236'), ('m', 'Montenegro')]
# [('p', 'http://www.wikidata.org/entity/Q27449'), ('name', 'Southern Europe'), ('cname', 'http://www.wikidata.org/entity/Q237'), ('m', 'Vatican City')]
# [('p', 'http://www.wikidata.org/entity/Q27449'), ('name', 'Southern Europe'), ('cname', 'http://www.wikidata.org/entity/Q238'), ('m', 'San Marino')]
# [('p', 'http://www.wikidata.org/entity/Q27479'), ('name', 'Northern Europe'), ('cname', 'http://www.wikidata.org/entity/Q25230'), ('m', 'Guernsey')]
# [('p', 'http://www.wikidata.org/entity/Q27509'), ('name', 'Central Europe'), ('cname', 'http://www.wikidata.org/entity/Q27'), ('m', 'Ireland')]
# [('p', 'http://www.wikidata.org/entity/Q27468'), ('name', 'Eastern Europe'), ('cname', 'http://www.wikidata.org/entity/Q28'), ('m', 'Hungary')]
# [('p', 'http://www.wikidata.org/entity/Q27509'), ('name', 'Central Europe'), ('cname', 'http://www.wikidata.org/entity/Q28'), ('m', 'Hungary')]
# [('p', 'http://www.wikidata.org/entity/Q27449'), ('name', 'Southern Europe'), ('cname', 'http://www.wikidata.org/entity/Q29'), ('m', 'Spain')]
# [('p', 'http://www.wikidata.org/entity/Q27496'), ('name', 'Western Europe'), ('cname', 'http://www.wikidata.org/entity/Q31'), ('m', 'Belgium')]
# [('p', 'http://www.wikidata.org/entity/Q27509'), ('name', 'Central Europe'), ('cname', 'http://www.wikidata.org/entity/Q31'), ('m', 'Belgium')]
# [('p', 'http://www.wikidata.org/entity/Q27496'), ('name', 'Western Europe'), ('cname', 'http://www.wikidata.org/entity/Q32'), ('m', 'Luxembourg')]
# [('p', 'http://www.wikidata.org/entity/Q27509'), ('name', 'Central Europe'), ('cname', 'http://www.wikidata.org/entity/Q32'), ('m', 'Luxembourg')]
# [('p', 'http://www.wikidata.org/entity/Q27479'), ('name', 'Northern Europe'), ('cname', 'http://www.wikidata.org/entity/Q33'), ('m', 'Finland')]
# [('p', 'http://www.wikidata.org/entity/Q27479'), ('name', 'Northern Europe'), ('cname', 'http://www.wikidata.org/entity/Q34'), ('m', 'Sweden')]
# [('p', 'http://www.wikidata.org/entity/Q27509'), ('name', 'Central Europe'), ('cname', 'http://www.wikidata.org/entity/Q347'), ('m', 'Liechtenstein')]
# [('p', 'http://www.wikidata.org/entity/Q27509'), ('name', 'Central Europe'), ('cname', 'http://www.wikidata.org/entity/Q35'), ('m', 'Denmark')]
# [('p', 'http://www.wikidata.org/entity/Q27479'), ('name', 'Northern Europe'), ('cname', 'http://www.wikidata.org/entity/Q35'), ('m', 'Denmark')]
# [('p', 'http://www.wikidata.org/entity/Q27468'), ('name', 'Eastern Europe'), ('cname', 'http://www.wikidata.org/entity/Q36'), ('m', 'Poland')]
# [('p', 'http://www.wikidata.org/entity/Q27509'), ('name', 'Central Europe'), ('cname', 'http://www.wikidata.org/entity/Q36'), ('m', 'Poland')]
# [('p', 'http://www.wikidata.org/entity/Q27479'), ('name', 'Northern Europe'), ('cname', 'http://www.wikidata.org/entity/Q37'), ('m', 'Lithuania')]
# [('p', 'http://www.wikidata.org/entity/Q27449'), ('name', 'Southern Europe'), ('cname', 'http://www.wikidata.org/entity/Q38'), ('m', 'Italy')]
# [('p', 'http://www.wikidata.org/entity/Q27496'), ('name', 'Western Europe'), ('cname', 'http://www.wikidata.org/entity/Q39'), ('m', 'Switzerland')]
# [('p', 'http://www.wikidata.org/entity/Q27509'), ('name', 'Central Europe'), ('cname', 'http://www.wikidata.org/entity/Q39'), ('m', 'Switzerland')]
# [('p', 'http://www.wikidata.org/entity/Q27496'), ('name', 'Western Europe'), ('cname', 'http://www.wikidata.org/entity/Q40'), ('m', 'Austria')]
# [('p', 'http://www.wikidata.org/entity/Q27509'), ('name', 'Central Europe'), ('cname', 'http://www.wikidata.org/entity/Q40'), ('m', 'Austria')]
# [('p', 'http://www.wikidata.org/entity/Q27449'), ('name', 'Southern Europe'), ('cname', 'http://www.wikidata.org/entity/Q403'), ('m', 'Serbia')]
# [('p', 'http://www.wikidata.org/entity/Q27449'), ('name', 'Southern Europe'), ('cname', 'http://www.wikidata.org/entity/Q41'), ('m', 'Greece')]
# [('p', 'http://www.wikidata.org/entity/Q27449'), ('name', 'Southern Europe'), ('cname', 'http://www.wikidata.org/entity/Q45'), ('m', 'Portugal')]
# [('p', 'http://www.wikidata.org/entity/Q27479'), ('name', 'Northern Europe'), ('cname', 'http://www.wikidata.org/entity/Q4628'), ('m', 'Faroe Islands')]
# [('p', 'http://www.wikidata.org/entity/Q27496'), ('name', 'Western Europe'), ('cname', 'http://www.wikidata.org/entity/Q55'), ('m', 'Netherlands')]
# [('p', 'http://www.wikidata.org/entity/Q27509'), ('name', 'Central Europe'), ('cname', 'http://www.wikidata.org/entity/Q55'), ('m', 'Netherlands')]
# [('p', 'http://www.wikidata.org/entity/Q27479'), ('name', 'Northern Europe'), ('cname', 'http://www.wikidata.org/entity/Q785'), ('m', 'Jersey')]
# [('p', 'http://www.wikidata.org/entity/Q27468'), ('name', 'Eastern Europe'), ('cname', 'http://www.wikidata.org/entity/Q875134'), ('m', 'European Russia')]
# [('p', 'http://www.wikidata.org/entity/Q27479'), ('name', 'Northern Europe'), ('cname', 'http://www.wikidata.org/entity/Q9676'), ('m', 'Isle of Man')]
# [('p', 'http://www.wikidata.org/entity/Q27479'), ('name', 'Northern Europe'), ('cname', 'http://www.wikidata.org/entity/Q3405693'), ('m', 'Sark')]
# [('p', 'http://www.wikidata.org/entity/Q27479'), ('name', 'Northern Europe'), ('cname', 'http://www.wikidata.org/entity/Q5689'), ('m', 'Åland')]
# [('p', 'http://www.wikidata.org/entity/Q27479'), ('name', 'Northern Europe'), ('cname', 'http://www.wikidata.org/entity/Q842829'), ('m', 'Svalbard and Jan Mayen')]
# [('p', 'http://www.wikidata.org/entity/Q27468'), ('name', 'Eastern Europe'), ('cname', 'http://www.wikidata.org/entity/Q19715270'), ('m', 'European Kazakhstan')]
# 66

# %%
#Using Europe to find all countries 
#[('p', 'http://www.wikidata.org/entity/Q46'), ('name', 'Europe')]
queryString = """
SELECT DISTINCT ?cname ?m 
WHERE {
   # bind something
     wd:Q46 wdt:P527 ?p.
     # ?p wdt:P527 ?cname.
   # get the label
   #?pn sc:name ?pname.
   # ?cname sc:name ?m.
}
LIMIT 200
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('cname', 'http://www.wikidata.org/entity/Q1410'), ('m', 'Gibraltar')]
# [('cname', 'http://www.wikidata.org/entity/Q142'), ('m', 'France')]
# [('cname', 'http://www.wikidata.org/entity/Q145'), ('m', 'United Kingdom')]
# [('cname', 'http://www.wikidata.org/entity/Q183'), ('m', 'Germany')]
# [('cname', 'http://www.wikidata.org/entity/Q184'), ('m', 'Belarus')]
# [('cname', 'http://www.wikidata.org/entity/Q189'), ('m', 'Iceland')]
# [('cname', 'http://www.wikidata.org/entity/Q191'), ('m', 'Estonia')]
# [('cname', 'http://www.wikidata.org/entity/Q20'), ('m', 'Norway')]
# [('cname', 'http://www.wikidata.org/entity/Q211'), ('m', 'Latvia')]
# [('cname', 'http://www.wikidata.org/entity/Q212'), ('m', 'Ukraine')]
# [('cname', 'http://www.wikidata.org/entity/Q213'), ('m', 'Czech Republic')]
# [('cname', 'http://www.wikidata.org/entity/Q214'), ('m', 'Slovakia')]
# [('cname', 'http://www.wikidata.org/entity/Q215'), ('m', 'Slovenia')]
# [('cname', 'http://www.wikidata.org/entity/Q217'), ('m', 'Moldova')]
# [('cname', 'http://www.wikidata.org/entity/Q218'), ('m', 'Romania')]
# [('cname', 'http://www.wikidata.org/entity/Q219'), ('m', 'Bulgaria')]
# [('cname', 'http://www.wikidata.org/entity/Q221'), ('m', 'North Macedonia')]
# [('cname', 'http://www.wikidata.org/entity/Q222'), ('m', 'Albania')]
# [('cname', 'http://www.wikidata.org/entity/Q224'), ('m', 'Croatia')]
# [('cname', 'http://www.wikidata.org/entity/Q225'), ('m', 'Bosnia and Herzegovina')]
# [('cname', 'http://www.wikidata.org/entity/Q228'), ('m', 'Andorra')]
# [('cname', 'http://www.wikidata.org/entity/Q233'), ('m', 'Malta')]
# [('cname', 'http://www.wikidata.org/entity/Q235'), ('m', 'Monaco')]
# [('cname', 'http://www.wikidata.org/entity/Q236'), ('m', 'Montenegro')]
# [('cname', 'http://www.wikidata.org/entity/Q237'), ('m', 'Vatican City')]
# [('cname', 'http://www.wikidata.org/entity/Q238'), ('m', 'San Marino')]
# [('cname', 'http://www.wikidata.org/entity/Q25230'), ('m', 'Guernsey')]
# [('cname', 'http://www.wikidata.org/entity/Q27'), ('m', 'Ireland')]
# [('cname', 'http://www.wikidata.org/entity/Q28'), ('m', 'Hungary')]
# [('cname', 'http://www.wikidata.org/entity/Q29'), ('m', 'Spain')]
# [('cname', 'http://www.wikidata.org/entity/Q31'), ('m', 'Belgium')]
# [('cname', 'http://www.wikidata.org/entity/Q32'), ('m', 'Luxembourg')]
# [('cname', 'http://www.wikidata.org/entity/Q33'), ('m', 'Finland')]
# [('cname', 'http://www.wikidata.org/entity/Q34'), ('m', 'Sweden')]
# [('cname', 'http://www.wikidata.org/entity/Q347'), ('m', 'Liechtenstein')]
# [('cname', 'http://www.wikidata.org/entity/Q35'), ('m', 'Denmark')]
# [('cname', 'http://www.wikidata.org/entity/Q36'), ('m', 'Poland')]
# [('cname', 'http://www.wikidata.org/entity/Q37'), ('m', 'Lithuania')]
# [('cname', 'http://www.wikidata.org/entity/Q38'), ('m', 'Italy')]
# [('cname', 'http://www.wikidata.org/entity/Q39'), ('m', 'Switzerland')]
# [('cname', 'http://www.wikidata.org/entity/Q40'), ('m', 'Austria')]
# [('cname', 'http://www.wikidata.org/entity/Q403'), ('m', 'Serbia')]
# [('cname', 'http://www.wikidata.org/entity/Q41'), ('m', 'Greece')]
# [('cname', 'http://www.wikidata.org/entity/Q45'), ('m', 'Portugal')]
# [('cname', 'http://www.wikidata.org/entity/Q4628'), ('m', 'Faroe Islands')]
# [('cname', 'http://www.wikidata.org/entity/Q55'), ('m', 'Netherlands')]
# [('cname', 'http://www.wikidata.org/entity/Q785'), ('m', 'Jersey')]
# [('cname', 'http://www.wikidata.org/entity/Q875134'), ('m', 'European Russia')]
# [('cname', 'http://www.wikidata.org/entity/Q9676'), ('m', 'Isle of Man')]
# [('cname', 'http://www.wikidata.org/entity/Q3405693'), ('m', 'Sark')]
# [('cname', 'http://www.wikidata.org/entity/Q5689'), ('m', 'Åland')]
# [('cname', 'http://www.wikidata.org/entity/Q842829'), ('m', 'Svalbard and Jan Mayen')]
# [('cname', 'http://www.wikidata.org/entity/Q19715270'), ('m', 'European Kazakhstan')]
# 53

# %%
#Since we have all the countries from europe and Leagues 
#
#[('p', 'http://www.wikidata.org/entity/Q46'), ('name', 'Europe')]
queryString = """
SELECT DISTINCT ?lc ?lcname (COUNT(?l) AS ?NumOfLea) 
WHERE {
   # bind something
     wd:Q46 wdt:P527 ?p.
     # ?p wdt:P527 ?cname.
     # ?l ?obj wd:Q15991303;
         wdt:P17 ?lc.
   # get the label
   #?pn sc:name ?pname.
   #?cname sc:name ?m.
   # ?lc sc:name ?lcname.
}
GROUP BY ?lc ?lcname 
LIMIT 200
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('lc', 'http://www.wikidata.org/entity/Q218'), ('lcname', 'Romania'), ('NumOfLea', '4092')]
# [('lc', 'http://www.wikidata.org/entity/Q28'), ('lcname', 'Hungary'), ('NumOfLea', '330')]
# [('lc', 'http://www.wikidata.org/entity/Q754'), ('lcname', 'Trinidad and Tobago'), ('NumOfLea', '132')]
# [('lc', 'http://www.wikidata.org/entity/Q865'), ('lcname', 'Taiwan'), ('NumOfLea', '198')]
# [('lc', 'http://www.wikidata.org/entity/Q921'), ('lcname', 'Brunei'), ('NumOfLea', '66')]
# [('lc', 'http://www.wikidata.org/entity/Q953'), ('lcname', 'Zambia'), ('NumOfLea', '132')]
# [('lc', 'http://www.wikidata.org/entity/Q1044'), ('lcname', 'Sierra Leone'), ('NumOfLea', '66')]
# [('lc', 'http://www.wikidata.org/entity/Q215'), ('lcname', 'Slovenia'), ('NumOfLea', '264')]
# [('lc', 'http://www.wikidata.org/entity/Q222'), ('lcname', 'Albania'), ('NumOfLea', '198')]
# [('lc', 'http://www.wikidata.org/entity/Q232'), ('lcname', 'Kazakhstan'), ('NumOfLea', '198')]
# [('lc', 'http://www.wikidata.org/entity/Q424'), ('lcname', 'Cambodia'), ('NumOfLea', '66')]
# [('lc', 'http://www.wikidata.org/entity/Q854'), ('lcname', 'Sri Lanka'), ('NumOfLea', '66')]
# [('lc', 'http://www.wikidata.org/entity/Q929'), ('lcname', 'Central African Republic'), ('NumOfLea', '66')]
# [('lc', 'http://www.wikidata.org/entity/Q962'), ('lcname', 'Benin'), ('NumOfLea', '66')]
# [('lc', 'http://www.wikidata.org/entity/Q963'), ('lcname', 'Botswana'), ('NumOfLea', '66')]
# [('lc', 'http://www.wikidata.org/entity/Q967'), ('lcname', 'Burundi'), ('NumOfLea', '66')]
# [('lc', 'http://www.wikidata.org/entity/Q974'), ('lcname', 'Democratic Republic of the Congo'), ('NumOfLea', '66')]
# [('lc', 'http://www.wikidata.org/entity/Q15282'), ('lcname', 'Nuevo León'), ('NumOfLea', '66')]
# [('lc', 'http://www.wikidata.org/entity/Q1246'), ('lcname', 'Kosovo'), ('NumOfLea', '198')]
# [('lc', 'http://www.wikidata.org/entity/Q16'), ('lcname', 'Canada'), ('NumOfLea', '1056')]
# [('lc', 'http://www.wikidata.org/entity/Q38'), ('lcname', 'Italy'), ('NumOfLea', '1056')]
# [('lc', 'http://www.wikidata.org/entity/Q664'), ('lcname', 'New Zealand'), ('NumOfLea', '660')]
# [('lc', 'http://www.wikidata.org/entity/Q778'), ('lcname', 'The Bahamas'), ('NumOfLea', '66')]
# [('lc', 'http://www.wikidata.org/entity/Q917'), ('lcname', 'Bhutan'), ('NumOfLea', '132')]
# [('lc', 'http://www.wikidata.org/entity/Q34754'), ('lcname', 'Somaliland'), ('NumOfLea', '66')]
# [('lc', 'http://www.wikidata.org/entity/Q1016'), ('lcname', 'Libya'), ('NumOfLea', '132')]
# [('lc', 'http://www.wikidata.org/entity/Q21203'), ('lcname', 'Aruba'), ('NumOfLea', '66')]
# [('lc', 'http://www.wikidata.org/entity/Q672'), ('lcname', 'Tuvalu'), ('NumOfLea', '132')]
# [('lc', 'http://www.wikidata.org/entity/Q691'), ('lcname', 'Papua New Guinea'), ('NumOfLea', '66')]
# [('lc', 'http://www.wikidata.org/entity/Q842'), ('lcname', 'Oman'), ('NumOfLea', '66')]
# [('lc', 'http://www.wikidata.org/entity/Q863'), ('lcname', 'Tajikistan'), ('NumOfLea', '66')]
# [('lc', 'http://www.wikidata.org/entity/Q786'), ('lcname', 'Dominican Republic'), ('NumOfLea', '132')]
# [('lc', 'http://www.wikidata.org/entity/Q183'), ('lcname', 'Germany'), ('NumOfLea', '8646')]
# [('lc', 'http://www.wikidata.org/entity/Q233'), ('lcname', 'Malta'), ('NumOfLea', '132')]
# [('lc', 'http://www.wikidata.org/entity/Q37'), ('lcname', 'Lithuania'), ('NumOfLea', '198')]
# [('lc', 'http://www.wikidata.org/entity/Q41'), ('lcname', 'Greece'), ('NumOfLea', '462')]
# [('lc', 'http://www.wikidata.org/entity/Q41304'), ('lcname', 'Weimar Republic'), ('NumOfLea', '66')]
# [('lc', 'http://www.wikidata.org/entity/Q796'), ('lcname', 'Iraq'), ('NumOfLea', '132')]
# [('lc', 'http://www.wikidata.org/entity/Q843'), ('lcname', 'Pakistan'), ('NumOfLea', '132')]
# [('lc', 'http://www.wikidata.org/entity/Q858'), ('lcname', 'Syria'), ('NumOfLea', '132')]
# [('lc', 'http://www.wikidata.org/entity/Q1007'), ('lcname', 'Guinea-Bissau'), ('NumOfLea', '66')]
# [('lc', 'http://www.wikidata.org/entity/Q1019'), ('lcname', 'Madagascar'), ('NumOfLea', '66')]
# [('lc', 'http://www.wikidata.org/entity/Q1025'), ('lcname', 'Mauritania'), ('NumOfLea', '66')]
# [('lc', 'http://www.wikidata.org/entity/Q1042'), ('lcname', 'Seychelles'), ('NumOfLea', '66')]
# [('lc', 'http://www.wikidata.org/entity/Q189'), ('lcname', 'Iceland'), ('NumOfLea', '264')]
# [('lc', 'http://www.wikidata.org/entity/Q238'), ('lcname', 'San Marino'), ('NumOfLea', '66')]
# [('lc', 'http://www.wikidata.org/entity/Q678'), ('lcname', 'Tonga'), ('NumOfLea', '66')]
# [('lc', 'http://www.wikidata.org/entity/Q736'), ('lcname', 'Ecuador'), ('NumOfLea', '132')]
# [('lc', 'http://www.wikidata.org/entity/Q763'), ('lcname', 'Saint Kitts and Nevis'), ('NumOfLea', '66')]
# [('lc', 'http://www.wikidata.org/entity/Q945'), ('lcname', 'Togo'), ('NumOfLea', '66')]
# [('lc', 'http://www.wikidata.org/entity/Q9676'), ('lcname', 'Isle of Man'), ('NumOfLea', '66')]
# [('lc', 'http://www.wikidata.org/entity/Q1050'), ('lcname', 'Eswatini'), ('NumOfLea', '66')]
# [('lc', 'http://www.wikidata.org/entity/Q155'), ('lcname', 'Brazil'), ('NumOfLea', '1716')]
# [('lc', 'http://www.wikidata.org/entity/Q174193'), ('lcname', 'United Kingdom of Great Britain and Ireland'), ('NumOfLea', '66')]
# [('lc', 'http://www.wikidata.org/entity/Q252'), ('lcname', 'Indonesia'), ('NumOfLea', '594')]
# [('lc', 'http://www.wikidata.org/entity/Q31'), ('lcname', 'Belgium'), ('NumOfLea', '726')]
# [('lc', 'http://www.wikidata.org/entity/Q34'), ('lcname', 'Sweden'), ('NumOfLea', '594')]
# [('lc', 'http://www.wikidata.org/entity/Q398'), ('lcname', 'Bahrain'), ('NumOfLea', '132')]
# [('lc', 'http://www.wikidata.org/entity/Q403'), ('lcname', 'Serbia'), ('NumOfLea', '858')]
# [('lc', 'http://www.wikidata.org/entity/Q419'), ('lcname', 'Peru'), ('NumOfLea', '330')]
# [('lc', 'http://www.wikidata.org/entity/Q790'), ('lcname', 'Haiti'), ('NumOfLea', '132')]
# [('lc', 'http://www.wikidata.org/entity/Q1000'), ('lcname', 'Gabon'), ('NumOfLea', '66')]
# [('lc', 'http://www.wikidata.org/entity/Q1041'), ('lcname', 'Senegal'), ('NumOfLea', '66')]
# [('lc', 'http://www.wikidata.org/entity/Q1049'), ('lcname', 'Sudan'), ('NumOfLea', '66')]
# [('lc', 'http://www.wikidata.org/entity/Q212'), ('lcname', 'Ukraine'), ('NumOfLea', '330')]
# [('lc', 'http://www.wikidata.org/entity/Q766'), ('lcname', 'Jamaica'), ('NumOfLea', '132')]
# [('lc', 'http://www.wikidata.org/entity/Q811'), ('lcname', 'Nicaragua'), ('NumOfLea', '66')]
# [('lc', 'http://www.wikidata.org/entity/Q837'), ('lcname', 'Nepal'), ('NumOfLea', '132')]
# [('lc', 'http://www.wikidata.org/entity/Q965'), ('lcname', 'Burkina Faso'), ('NumOfLea', '66')]
# [('lc', 'http://www.wikidata.org/entity/Q977'), ('lcname', 'Djibouti'), ('NumOfLea', '66')]
# [('lc', 'http://www.wikidata.org/entity/Q986'), ('lcname', 'Eritrea'), ('NumOfLea', '66')]
# [('lc', 'http://www.wikidata.org/entity/Q148'), ('lcname', "People's Republic of China"), ('NumOfLea', '396')]
# [('lc', 'http://www.wikidata.org/entity/Q236'), ('lcname', 'Montenegro'), ('NumOfLea', '264')]
# [('lc', 'http://www.wikidata.org/entity/Q29'), ('lcname', 'Spain'), ('NumOfLea', '2178')]
# [('lc', 'http://www.wikidata.org/entity/Q414'), ('lcname', 'Argentina'), ('NumOfLea', '1386')]
# [('lc', 'http://www.wikidata.org/entity/Q686'), ('lcname', 'Vanuatu'), ('NumOfLea', '132')]
# [('lc', 'http://www.wikidata.org/entity/Q733'), ('lcname', 'Paraguay'), ('NumOfLea', '396')]
# [('lc', 'http://www.wikidata.org/entity/Q851'), ('lcname', 'Saudi Arabia'), ('NumOfLea', '396')]
# [('lc', 'http://www.wikidata.org/entity/Q902'), ('lcname', 'Bangladesh'), ('NumOfLea', '198')]
# [('lc', 'http://www.wikidata.org/entity/Q948'), ('lcname', 'Tunisia'), ('NumOfLea', '660')]
# [('lc', 'http://www.wikidata.org/entity/Q1006'), ('lcname', 'Guinea'), ('NumOfLea', '66')]
# [('lc', 'http://www.wikidata.org/entity/Q1014'), ('lcname', 'Liberia'), ('NumOfLea', '66')]
# [('lc', 'http://www.wikidata.org/entity/Q1037'), ('lcname', 'Rwanda'), ('NumOfLea', '66')]
# [('lc', 'http://www.wikidata.org/entity/Q217'), ('lcname', 'Moldova'), ('NumOfLea', '264')]
# [('lc', 'http://www.wikidata.org/entity/Q258'), ('lcname', 'South Africa'), ('NumOfLea', '264')]
# [('lc', 'http://www.wikidata.org/entity/Q265'), ('lcname', 'Uzbekistan'), ('NumOfLea', '132')]
# [('lc', 'http://www.wikidata.org/entity/Q31354462'), ('lcname', 'Republic of Abkhazia'), ('NumOfLea', '66')]
# [('lc', 'http://www.wikidata.org/entity/Q334'), ('lcname', 'Singapore'), ('NumOfLea', '66')]
# [('lc', 'http://www.wikidata.org/entity/Q685'), ('lcname', 'Solomon Islands'), ('NumOfLea', '66')]
# [('lc', 'http://www.wikidata.org/entity/Q760'), ('lcname', 'Saint Lucia'), ('NumOfLea', '66')]
# [('lc', 'http://www.wikidata.org/entity/Q79'), ('lcname', 'Egypt'), ('NumOfLea', '198')]
# [('lc', 'http://www.wikidata.org/entity/Q819'), ('lcname', 'Laos'), ('NumOfLea', '66')]
# [('lc', 'http://www.wikidata.org/entity/Q912'), ('lcname', 'Mali'), ('NumOfLea', '66')]
# [('lc', 'http://www.wikidata.org/entity/Q37024'), ('lcname', 'Serbia and Montenegro'), ('NumOfLea', '66')]
# [('lc', 'http://www.wikidata.org/entity/Q224'), ('lcname', 'Croatia'), ('NumOfLea', '330')]
# [('lc', 'http://www.wikidata.org/entity/Q225'), ('lcname', 'Bosnia and Herzegovina'), ('NumOfLea', '528')]
# [('lc', 'http://www.wikidata.org/entity/Q242'), ('lcname', 'Belize'), ('NumOfLea', '198')]
# [('lc', 'http://www.wikidata.org/entity/Q33'), ('lcname', 'Finland'), ('NumOfLea', '990')]
# [('lc', 'http://www.wikidata.org/entity/Q40'), ('lcname', 'Austria'), ('NumOfLea', '792')]
# [('lc', 'http://www.wikidata.org/entity/Q668'), ('lcname', 'India'), ('NumOfLea', '264')]
# [('lc', 'http://www.wikidata.org/entity/Q869'), ('lcname', 'Thailand'), ('NumOfLea', '396')]
# [('lc', 'http://www.wikidata.org/entity/Q924'), ('lcname', 'Tanzania'), ('NumOfLea', '132')]
# [('lc', 'http://www.wikidata.org/entity/Q958'), ('lcname', 'South Sudan'), ('NumOfLea', '66')]
# [('lc', 'http://www.wikidata.org/entity/Q1005'), ('lcname', 'The Gambia'), ('NumOfLea', '132')]
# [('lc', 'http://www.wikidata.org/entity/Q1029'), ('lcname', 'Mozambique'), ('NumOfLea', '66')]
# [('lc', 'http://www.wikidata.org/entity/Q1039'), ('lcname', 'São Tomé and Príncipe'), ('NumOfLea', '66')]
# [('lc', 'http://www.wikidata.org/entity/Q142'), ('lcname', 'France'), ('NumOfLea', '792')]
# [('lc', 'http://www.wikidata.org/entity/Q184'), ('lcname', 'Belarus'), ('NumOfLea', '198')]
# [('lc', 'http://www.wikidata.org/entity/Q241'), ('lcname', 'Cuba'), ('NumOfLea', '66')]
# [('lc', 'http://www.wikidata.org/entity/Q32'), ('lcname', 'Luxembourg'), ('NumOfLea', '198')]
# [('lc', 'http://www.wikidata.org/entity/Q347'), ('lcname', 'Liechtenstein'), ('NumOfLea', '66')]
# [('lc', 'http://www.wikidata.org/entity/Q750'), ('lcname', 'Bolivia'), ('NumOfLea', '132')]
# [('lc', 'http://www.wikidata.org/entity/Q792'), ('lcname', 'El Salvador'), ('NumOfLea', '132')]
# [('lc', 'http://www.wikidata.org/entity/Q874'), ('lcname', 'Turkmenistan'), ('NumOfLea', '66')]
# [('lc', 'http://www.wikidata.org/entity/Q971'), ('lcname', 'Republic of the Congo'), ('NumOfLea', '66')]
# [('lc', 'http://www.wikidata.org/entity/Q1030'), ('lcname', 'Namibia'), ('NumOfLea', '198')]
# [('lc', 'http://www.wikidata.org/entity/Q1206012'), ('lcname', 'German Reich'), ('NumOfLea', '1122')]
# [('lc', 'http://www.wikidata.org/entity/Q221'), ('lcname', 'North Macedonia'), ('NumOfLea', '198')]
# [('lc', 'http://www.wikidata.org/entity/Q36'), ('lcname', 'Poland'), ('NumOfLea', '990')]
# [('lc', 'http://www.wikidata.org/entity/Q774'), ('lcname', 'Guatemala'), ('NumOfLea', '198')]
# [('lc', 'http://www.wikidata.org/entity/Q783'), ('lcname', 'Honduras'), ('NumOfLea', '198')]
# [('lc', 'http://www.wikidata.org/entity/Q188161'), ('lcname', 'Dutch East Indies'), ('NumOfLea', '66')]
# [('lc', 'http://www.wikidata.org/entity/Q223'), ('lcname', 'Greenland'), ('NumOfLea', '66')]
# [('lc', 'http://www.wikidata.org/entity/Q1036'), ('lcname', 'Uganda'), ('NumOfLea', '66')]
# [('lc', 'http://www.wikidata.org/entity/Q4628'), ('lcname', 'Faroe Islands'), ('NumOfLea', '132')]
# [('lc', 'http://www.wikidata.org/entity/Q730'), ('lcname', 'Suriname'), ('NumOfLea', '132')]
# [('lc', 'http://www.wikidata.org/entity/Q878'), ('lcname', 'United Arab Emirates'), ('NumOfLea', '132')]
# [('lc', 'http://www.wikidata.org/entity/Q881'), ('lcname', 'Vietnam'), ('NumOfLea', '198')]
# [('lc', 'http://www.wikidata.org/entity/Q983'), ('lcname', 'Equatorial Guinea'), ('NumOfLea', '66')]
# [('lc', 'http://www.wikidata.org/entity/Q1028'), ('lcname', 'Morocco'), ('NumOfLea', '330')]
# [('lc', 'http://www.wikidata.org/entity/Q1045'), ('lcname', 'Somalia'), ('NumOfLea', '198')]
# [('lc', 'http://www.wikidata.org/entity/Q172579'), ('lcname', 'Kingdom of Italy'), ('NumOfLea', '132')]
# [('lc', 'http://www.wikidata.org/entity/Q213'), ('lcname', 'Czech Republic'), ('NumOfLea', '13200')]
# [('lc', 'http://www.wikidata.org/entity/Q229'), ('lcname', 'Cyprus'), ('NumOfLea', '858')]
# [('lc', 'http://www.wikidata.org/entity/Q298'), ('lcname', 'Chile'), ('NumOfLea', '462')]
# [('lc', 'http://www.wikidata.org/entity/Q423'), ('lcname', 'North Korea'), ('NumOfLea', '132')]
# [('lc', 'http://www.wikidata.org/entity/Q717'), ('lcname', 'Venezuela'), ('NumOfLea', '198')]
# [('lc', 'http://www.wikidata.org/entity/Q769'), ('lcname', 'Grenada'), ('NumOfLea', '66')]
# [('lc', 'http://www.wikidata.org/entity/Q822'), ('lcname', 'Lebanon'), ('NumOfLea', '264')]
# [('lc', 'http://www.wikidata.org/entity/Q884'), ('lcname', 'South Korea'), ('NumOfLea', '6204')]
# [('lc', 'http://www.wikidata.org/entity/Q1009'), ('lcname', 'Cameroon'), ('NumOfLea', '132')]
# [('lc', 'http://www.wikidata.org/entity/Q1032'), ('lcname', 'Niger'), ('NumOfLea', '66')]
# [('lc', 'http://www.wikidata.org/entity/Q114'), ('lcname', 'Kenya'), ('NumOfLea', '132')]
# [('lc', 'http://www.wikidata.org/entity/Q227'), ('lcname', 'Azerbaijan'), ('NumOfLea', '132')]
# [('lc', 'http://www.wikidata.org/entity/Q45'), ('lcname', 'Portugal'), ('NumOfLea', '396')]
# [('lc', 'http://www.wikidata.org/entity/Q695'), ('lcname', 'Palau'), ('NumOfLea', '66')]
# [('lc', 'http://www.wikidata.org/entity/Q805'), ('lcname', 'Yemen'), ('NumOfLea', '66')]
# [('lc', 'http://www.wikidata.org/entity/Q817'), ('lcname', 'Kuwait'), ('NumOfLea', '66')]
# [('lc', 'http://www.wikidata.org/entity/Q1011'), ('lcname', 'Cape Verde'), ('NumOfLea', '132')]
# [('lc', 'http://www.wikidata.org/entity/Q17'), ('lcname', 'Japan'), ('NumOfLea', '726')]
# [('lc', 'http://www.wikidata.org/entity/Q20'), ('lcname', 'Norway'), ('NumOfLea', '4752')]
# [('lc', 'http://www.wikidata.org/entity/Q214'), ('lcname', 'Slovakia'), ('NumOfLea', '330')]
# [('lc', 'http://www.wikidata.org/entity/Q262'), ('lcname', 'Algeria'), ('NumOfLea', '396')]
# [('lc', 'http://www.wikidata.org/entity/Q27'), ('lcname', 'Ireland'), ('NumOfLea', '462')]
# [('lc', 'http://www.wikidata.org/entity/Q30'), ('lcname', 'United States of America'), ('NumOfLea', '1650')]
# [('lc', 'http://www.wikidata.org/entity/Q35'), ('lcname', 'Denmark'), ('NumOfLea', '528')]
# [('lc', 'http://www.wikidata.org/entity/Q408'), ('lcname', 'Australia'), ('NumOfLea', '1254')]
# [('lc', 'http://www.wikidata.org/entity/Q55'), ('lcname', 'Netherlands'), ('NumOfLea', '1452')]
# [('lc', 'http://www.wikidata.org/entity/Q683'), ('lcname', 'Samoa'), ('NumOfLea', '66')]
# [('lc', 'http://www.wikidata.org/entity/Q734'), ('lcname', 'Guyana'), ('NumOfLea', '132')]
# [('lc', 'http://www.wikidata.org/entity/Q784'), ('lcname', 'Dominica'), ('NumOfLea', '66')]
# [('lc', 'http://www.wikidata.org/entity/Q1033'), ('lcname', 'Nigeria'), ('NumOfLea', '66')]
# [('lc', 'http://www.wikidata.org/entity/Q574'), ('lcname', 'East Timor'), ('NumOfLea', '66')]
# [('lc', 'http://www.wikidata.org/entity/Q657'), ('lcname', 'Chad'), ('NumOfLea', '66')]
# [('lc', 'http://www.wikidata.org/entity/Q711'), ('lcname', 'Mongolia'), ('NumOfLea', '66')]
# [('lc', 'http://www.wikidata.org/entity/Q781'), ('lcname', 'Antigua and Barbuda'), ('NumOfLea', '66')]
# [('lc', 'http://www.wikidata.org/entity/Q800'), ('lcname', 'Costa Rica'), ('NumOfLea', '198')]
# [('lc', 'http://www.wikidata.org/entity/Q804'), ('lcname', 'Panama'), ('NumOfLea', '132')]
# [('lc', 'http://www.wikidata.org/entity/Q810'), ('lcname', 'Jordan'), ('NumOfLea', '66')]
# [('lc', 'http://www.wikidata.org/entity/Q813'), ('lcname', 'Kyrgyzstan'), ('NumOfLea', '66')]
# [('lc', 'http://www.wikidata.org/entity/Q833'), ('lcname', 'Malaysia'), ('NumOfLea', '198')]
# [('lc', 'http://www.wikidata.org/entity/Q916'), ('lcname', 'Angola'), ('NumOfLea', '66')]
# [('lc', 'http://www.wikidata.org/entity/Q145'), ('lcname', 'United Kingdom'), ('NumOfLea', '6006')]
# [('lc', 'http://www.wikidata.org/entity/Q159'), ('lcname', 'Russia'), ('NumOfLea', '660')]
# [('lc', 'http://www.wikidata.org/entity/Q211'), ('lcname', 'Latvia'), ('NumOfLea', '264')]
# [('lc', 'http://www.wikidata.org/entity/Q230'), ('lcname', 'Georgia'), ('NumOfLea', '264')]
# [('lc', 'http://www.wikidata.org/entity/Q39'), ('lcname', 'Switzerland'), ('NumOfLea', '462')]
# [('lc', 'http://www.wikidata.org/entity/Q77'), ('lcname', 'Uruguay'), ('NumOfLea', '330')]
# [('lc', 'http://www.wikidata.org/entity/Q96'), ('lcname', 'Mexico'), ('NumOfLea', '528')]
# [('lc', 'http://www.wikidata.org/entity/Q33946'), ('lcname', 'Czechoslovakia'), ('NumOfLea', '132')]
# [('lc', 'http://www.wikidata.org/entity/Q1008'), ('lcname', 'Ivory Coast'), ('NumOfLea', '132')]
# [('lc', 'http://www.wikidata.org/entity/Q1013'), ('lcname', 'Lesotho'), ('NumOfLea', '66')]
# [('lc', 'http://www.wikidata.org/entity/Q1020'), ('lcname', 'Malawi'), ('NumOfLea', '66')]
# [('lc', 'http://www.wikidata.org/entity/Q1027'), ('lcname', 'Mauritius'), ('NumOfLea', '66')]
# [('lc', 'http://www.wikidata.org/entity/Q13353'), ('lcname', 'Montserrat'), ('NumOfLea', '66')]
# [('lc', 'http://www.wikidata.org/entity/Q15180'), ('lcname', 'Soviet Union'), ('NumOfLea', '132')]
# [('lc', 'http://www.wikidata.org/entity/Q191'), ('lcname', 'Estonia'), ('NumOfLea', '528')]
# [('lc', 'http://www.wikidata.org/entity/Q43'), ('lcname', 'Turkey'), ('NumOfLea', '396')]
# [('lc', 'http://www.wikidata.org/entity/Q739'), ('lcname', 'Colombia'), ('NumOfLea', '132')]
# [('lc', 'http://www.wikidata.org/entity/Q757'), ('lcname', 'Saint Vincent and the Grenadines'), ('NumOfLea', '66')]
# [('lc', 'http://www.wikidata.org/entity/Q794'), ('lcname', 'Iran'), ('NumOfLea', '264')]
# [('lc', 'http://www.wikidata.org/entity/Q826'), ('lcname', 'Maldives'), ('NumOfLea', '66')]
# [('lc', 'http://www.wikidata.org/entity/Q846'), ('lcname', 'Qatar'), ('NumOfLea', '132')]
# [('lc', 'http://www.wikidata.org/entity/Q889'), ('lcname', 'Afghanistan'), ('NumOfLea', '66')]
# [('lc', 'http://www.wikidata.org/entity/Q954'), ('lcname', 'Zimbabwe'), ('NumOfLea', '66')]
# [('lc', 'http://www.wikidata.org/entity/Q218272'), ('lcname', 'Algeria'), ('NumOfLea', '66')]
# [('lc', 'http://www.wikidata.org/entity/Q117'), ('lcname', 'Ghana'), ('NumOfLea', '132')]
# [('lc', 'http://www.wikidata.org/entity/Q219060'), ('lcname', 'State of Palestine'), ('NumOfLea', '132')]
# [('lc', 'http://www.wikidata.org/entity/Q713750'), ('lcname', 'West Germany'), ('NumOfLea', '1188')]
# [('lc', 'http://www.wikidata.org/entity/Q836'), ('lcname', 'Myanmar'), ('NumOfLea', '132')]
# 200

# %% [markdown]
# Final query for this task

# %%
# write your final query

# %% [markdown]
# ## Task 5
# Identify the BGP for the ballon d'Or award

# %%
#Using Ronaldos BGP to explore awards
queryString = """
SELECT DISTINCT ?p ?name
WHERE {
   # bind something
   wd:Q11571 ?p ?obj .
   # get the label
   # ?p sc:name ?name.
}
LIMIT 200
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P1005'), ('name', 'Portuguese National Library ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1006'), ('name', 'Nationale Thesaurus voor Auteurs ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1015'), ('name', 'NORAF ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P103'), ('name', 'native language')]
# [('p', 'http://www.wikidata.org/prop/direct/P1038'), ('name', 'relative')]
# [('p', 'http://www.wikidata.org/prop/direct/P1050'), ('name', 'medical condition')]
# [('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('p', 'http://www.wikidata.org/prop/direct/P109'), ('name', 'signature')]
# [('p', 'http://www.wikidata.org/prop/direct/P118'), ('name', 'league')]
# [('p', 'http://www.wikidata.org/prop/direct/P1263'), ('name', 'NNDB people ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1266'), ('name', 'AlloCiné person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1273'), ('name', 'CANTIC ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1280'), ('name', 'CONOR.SI ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1284'), ('name', 'Munzinger person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1285'), ('name', 'Munzinger Sport number')]
# [('p', 'http://www.wikidata.org/prop/direct/P1296'), ('name', 'Gran Enciclopèdia Catalana ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1343'), ('name', 'described by source')]
# [('p', 'http://www.wikidata.org/prop/direct/P1344'), ('name', 'participant in')]
# [('p', 'http://www.wikidata.org/prop/direct/P1350'), ('name', 'number of matches played/races/starts')]
# [('p', 'http://www.wikidata.org/prop/direct/P1399'), ('name', 'convicted of')]
# [('p', 'http://www.wikidata.org/prop/direct/P1411'), ('name', 'nominated for')]
# [('p', 'http://www.wikidata.org/prop/direct/P1412'), ('name', 'languages spoken, written or signed')]
# [('p', 'http://www.wikidata.org/prop/direct/P1417'), ('name', 'Encyclopædia Britannica Online ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1447'), ('name', 'Sports-Reference.com Olympic athlete ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1469'), ('name', 'FIFA player ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1532'), ('name', 'country for sport')]
# [('p', 'http://www.wikidata.org/prop/direct/P1618'), ('name', 'sport number')]
# [('p', 'http://www.wikidata.org/prop/direct/P166'), ('name', 'award received')]
# [('p', 'http://www.wikidata.org/prop/direct/P1695'), ('name', 'NLP ID (unique)')]
# [('p', 'http://www.wikidata.org/prop/direct/P1741'), ('name', 'GTAA ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P18'), ('name', 'image')]
# [('p', 'http://www.wikidata.org/prop/direct/P1889'), ('name', 'different from')]
# [('p', 'http://www.wikidata.org/prop/direct/P19'), ('name', 'place of birth')]
# [('p', 'http://www.wikidata.org/prop/direct/P1971'), ('name', 'number of children')]
# [('p', 'http://www.wikidata.org/prop/direct/P2002'), ('name', 'Twitter username')]
# [('p', 'http://www.wikidata.org/prop/direct/P2003'), ('name', 'Instagram username')]
# [('p', 'http://www.wikidata.org/prop/direct/P2013'), ('name', 'Facebook ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2020'), ('name', 'WorldFootball.net player ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2031'), ('name', 'work period (start)')]
# [('p', 'http://www.wikidata.org/prop/direct/P2048'), ('name', 'height')]
# [('p', 'http://www.wikidata.org/prop/direct/P2067'), ('name', 'mass')]
# [('p', 'http://www.wikidata.org/prop/direct/P21'), ('name', 'sex or gender')]
# [('p', 'http://www.wikidata.org/prop/direct/P213'), ('name', 'ISNI')]
# [('p', 'http://www.wikidata.org/prop/direct/P214'), ('name', 'VIAF ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2163'), ('name', 'FAST ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2193'), ('name', 'Soccerbase player ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P22'), ('name', 'father')]
# [('p', 'http://www.wikidata.org/prop/direct/P227'), ('name', 'GND ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2276'), ('name', 'UEFA player ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2369'), ('name', 'Soccerway player ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P244'), ('name', 'Library of Congress authority ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2446'), ('name', 'Transfermarkt player ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P25'), ('name', 'mother')]
# [('p', 'http://www.wikidata.org/prop/direct/P2574'), ('name', 'National-Football-Teams.com player ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2600'), ('name', 'Geni.com profile ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2605'), ('name', 'ČSFD person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P268'), ('name', 'Bibliothèque nationale de France ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P269'), ('name', 'IdRef ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P27'), ('name', 'country of citizenship')]
# [('p', 'http://www.wikidata.org/prop/direct/P2924'), ('name', 'Great Russian Encyclopedia Online ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3043'), ('name', 'Scoresway soccer person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3047'), ('name', 'PlaymakerStats.com player ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('name', 'instance of')]
# [('p', 'http://www.wikidata.org/prop/direct/P3219'), ('name', 'Encyclopædia Universalis ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3221'), ('name', 'New York Times topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3222'), ('name', 'NE.se ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3342'), ('name', 'significant person')]
# [('p', 'http://www.wikidata.org/prop/direct/P3365'), ('name', 'Treccani ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3373'), ('name', 'sibling')]
# [('p', 'http://www.wikidata.org/prop/direct/P3388'), ('name', 'LittleSis people ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3417'), ('name', 'Quora topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3427'), ('name', 'AS.com athlete ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P345'), ('name', 'IMDb ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P349'), ('name', 'National Diet Library ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3509'), ('name', 'Dagens Nyheter topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3537'), ('name', 'FootballDatabase.eu player ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3553'), ('name', 'Zhihu topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3630'), ('name', 'Babelio author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3655'), ('name', 'BDFutbol player ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3665'), ('name', "L'Équipe football player ID")]
# [('p', 'http://www.wikidata.org/prop/direct/P3681'), ('name', 'ESPNFC.com player ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3726'), ('name', 'EU-Football.info player ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P373'), ('name', 'Commons category')]
# [('p', 'http://www.wikidata.org/prop/direct/P413'), ('name', 'position played on team / speciality')]
# [('p', 'http://www.wikidata.org/prop/direct/P4342'), ('name', 'Store norske leksikon ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P451'), ('name', 'unmarried partner')]
# [('p', 'http://www.wikidata.org/prop/direct/P4985'), ('name', 'TMDb person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5019'), ('name', 'Brockhaus Enzyklopädie online ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5034'), ('name', 'National Library of Korea ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5247'), ('name', 'Giant Bomb ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5284'), ('name', 'Douban movie celebrity ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5361'), ('name', 'BNB person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P54'), ('name', 'member of sports team')]
# [('p', 'http://www.wikidata.org/prop/direct/P5421'), ('name', 'Trading Card Database person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P551'), ('name', 'residence')]
# [('p', 'http://www.wikidata.org/prop/direct/P5587'), ('name', 'Libris-URI')]
# [('p', 'http://www.wikidata.org/prop/direct/P5617'), ('name', 'Evene ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P569'), ('name', 'date of birth')]
# [('p', 'http://www.wikidata.org/prop/direct/P5740'), ('name', 'So Foot ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5750'), ('name', 'FBref.com player ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6058'), ('name', 'Larousse ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6188'), ('name', 'BDFA player ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6327'), ('name', 'Goodreads character ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6379'), ('name', 'has works in the collection')]
# [('p', 'http://www.wikidata.org/prop/direct/P641'), ('name', 'sport')]
# [('p', 'http://www.wikidata.org/prop/direct/P646'), ('name', 'Freebase ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6509'), ('name', 'total goals in career')]
# [('p', 'http://www.wikidata.org/prop/direct/P6517'), ('name', 'WhoSampled artist ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6573'), ('name', 'Klexikon article ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6615'), ('name', 'Kicker.de player ID (former scheme)')]
# [('p', 'http://www.wikidata.org/prop/direct/P6849'), ('name', 'DR topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6868'), ('name', 'Hoopla artist ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P691'), ('name', 'NKCR AUT ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7293'), ('name', 'PLWABN ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P734'), ('name', 'family name')]
# [('p', 'http://www.wikidata.org/prop/direct/P735'), ('name', 'given name')]
# [('p', 'http://www.wikidata.org/prop/direct/P742'), ('name', 'pseudonym')]
# [('p', 'http://www.wikidata.org/prop/direct/P7666'), ('name', 'Visuotinė lietuvių enciklopedija ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7763'), ('name', 'copyright status as a creator')]
# [('p', 'http://www.wikidata.org/prop/direct/P7818'), ('name', 'French Vikidia ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7827'), ('name', 'Spanish Vikidia ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7829'), ('name', 'English Vikidia ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7859'), ('name', 'WorldCat Identities ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8286'), ('name', 'Olympedia people ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8349'), ('name', 'Proleksis enciklopedija ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P859'), ('name', 'sponsor')]
# [('p', 'http://www.wikidata.org/prop/direct/P8672'), ('name', 'Twitter topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8687'), ('name', 'social media followers')]
# [('p', 'http://www.wikidata.org/prop/direct/P8912'), ('name', 'Kicker.de player ID (actual scheme)')]
# [('p', 'http://www.wikidata.org/prop/direct/P898'), ('name', 'IPA transcription')]
# [('p', 'http://www.wikidata.org/prop/direct/P906'), ('name', 'SELIBR ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P910'), ('name', "topic's main category")]
# [('p', 'http://www.wikidata.org/prop/direct/P9368'), ('name', 'CNA topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P949'), ('name', 'National Library of Israel ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P950'), ('name', 'Biblioteca Nacional de España ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P9743'), ('name', 'Podchaser creator ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P9807'), ('name', 'SNK ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2458'), ('name', 'Mackolik.com player ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3579'), ('name', 'Sina Weibo user ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8780'), ('name', 'Portuguese Football Federation ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3046'), ('name', 'ForaDeJogo player ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7036'), ('name', 'TuttoCalciatori.net player ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8006'), ('name', 'footedness')]
# 143

# %%
#Using Award Recieved 
#[('p', 'http://www.wikidata.org/prop/direct/P166'), ('name', 'award received')]
queryString = """
SELECT DISTINCT ?p ?name
WHERE {
   # bind something
   wd:Q11571 wdt:P166 ?p.
   # get the label
   # ?p sc:name ?name.
}
LIMIT 200
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/entity/Q1750244'), ('name', 'FWA Footballer of the Year')]
# [('p', 'http://www.wikidata.org/entity/Q10726649'), ('name', "PFA Fans' Player of the Year")]
# [('p', 'http://www.wikidata.org/entity/Q20888805'), ('name', 'Commander of the Order of Merit of Portugal')]
# [('p', 'http://www.wikidata.org/entity/Q1146578'), ('name', 'UEFA Team of the Year')]
# [('p', 'http://www.wikidata.org/entity/Q182529'), ('name', 'FIFA World Player of the Year')]
# [('p', 'http://www.wikidata.org/entity/Q260117'), ('name', "UEFA Men's Player of the Year Award")]
# [('p', 'http://www.wikidata.org/entity/Q166177'), ('name', "Ballon d'Or")]
# [('p', 'http://www.wikidata.org/entity/Q20860117'), ('name', 'Officer of the Order of Prince Henry')]
# [('p', 'http://www.wikidata.org/entity/Q20859673'), ('name', 'Grand Officer of the Order of Prince Henry')]
# [('p', 'http://www.wikidata.org/entity/Q2986505'), ('name', 'Sir Matt Busby Player of the Year')]
# [('p', 'http://www.wikidata.org/entity/Q2291862'), ('name', "FIFA Ballon d'Or")]
# [('p', 'http://www.wikidata.org/entity/Q729513'), ('name', 'Pichichi Trophy')]
# [('p', 'http://www.wikidata.org/entity/Q233454'), ('name', 'European Golden Shoe')]
# [('p', 'http://www.wikidata.org/entity/Q2044044'), ('name', 'PFA Team of the Year')]
# [('p', 'http://www.wikidata.org/entity/Q616031'), ('name', 'FIFA Puskás Award')]
# [('p', 'http://www.wikidata.org/entity/Q4896696'), ('name', 'Best International Athlete ESPY Award')]
# [('p', 'http://www.wikidata.org/entity/Q621867'), ('name', "PFA Players' Player of the Year")]
# [('p', 'http://www.wikidata.org/entity/Q554495'), ('name', 'Bravo Award')]
# [('p', 'http://www.wikidata.org/entity/Q1049896'), ('name', "Onze d'Or")]
# [('p', 'http://www.wikidata.org/entity/Q1188692'), ('name', 'Premier League Player of the Season')]
# [('p', 'http://www.wikidata.org/entity/Q794775'), ('name', 'Premier League Golden Boot')]
# [('p', 'http://www.wikidata.org/entity/Q890790'), ('name', 'Premier League Player of the Month')]
# [('p', 'http://www.wikidata.org/entity/Q2009646'), ('name', 'PFA Young Player of the Year')]
# [('p', 'http://www.wikidata.org/entity/Q1808491'), ('name', 'Trofeo Alfredo Di Stéfano')]
# [('p', 'http://www.wikidata.org/entity/Q66504206'), ('name', 'Medal of Merit of the Order of the Immaculate Conception of Vila Viçosa')]
# [('p', 'http://www.wikidata.org/entity/Q15474655'), ('name', 'La Liga Player of the Month')]
# [('p', 'http://www.wikidata.org/entity/Q1187699'), ('name', 'UEFA Club Footballer of the Year')]
# 27

# %% [markdown]
# Final query for this task

# %%
# write your final query
#Using Ballon d'Or ID from Results
#[('p', 'http://www.wikidata.org/entity/Q166177'), ('name', "Ballon d'Or")]
queryString = """
SELECT DISTINCT ?p ?name
WHERE {
   # bind something
   wd:Q166177 ?p ?obj.
   # get the label
   # ?p sc:name ?name.
}
LIMIT 200
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P1346'), ('name', 'winner')]
# [('p', 'http://www.wikidata.org/prop/direct/P1424'), ('name', "topic's main template")]
# [('p', 'http://www.wikidata.org/prop/direct/P18'), ('name', 'image')]
# [('p', 'http://www.wikidata.org/prop/direct/P1889'), ('name', 'different from')]
# [('p', 'http://www.wikidata.org/prop/direct/P2572'), ('name', 'hashtag')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('name', 'subclass of')]
# [('p', 'http://www.wikidata.org/prop/direct/P2924'), ('name', 'Great Russian Encyclopedia Online ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('name', 'instance of')]
# [('p', 'http://www.wikidata.org/prop/direct/P3222'), ('name', 'NE.se ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P373'), ('name', 'Commons category')]
# [('p', 'http://www.wikidata.org/prop/direct/P571'), ('name', 'inception')]
# [('p', 'http://www.wikidata.org/prop/direct/P641'), ('name', 'sport')]
# [('p', 'http://www.wikidata.org/prop/direct/P646'), ('name', 'Freebase ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7818'), ('name', 'French Vikidia ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7822'), ('name', 'Italian Vikidia ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8408'), ('name', 'KBpedia ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P856'), ('name', 'official website')]
# [('p', 'http://www.wikidata.org/prop/direct/P910'), ('name', "topic's main category")]
# [('p', 'http://www.wikidata.org/prop/direct/P1027'), ('name', 'conferred by')]
# [('p', 'http://www.wikidata.org/prop/direct/P2517'), ('name', 'category for recipients of this award')]
# 20

# %% [markdown]
# ## Task 6
# Return the countries which have at least two different players of their nationality (consider the country of citizenship) who won the ballon d'Or (the result set must be a list of triples country IRI, label and #different players).

# %%
# Getting 2 IRIs from BGP of Ronaldo and Winner ID of Ballon d'Or award
#[('p', 'http://www.wikidata.org/prop/direct/P1532'), ('name', 'country for sport')]
#[('p', 'http://www.wikidata.org/prop/direct/P27'), ('name', 'country of citizenship')]
#[('p', 'http://www.wikidata.org/prop/direct/P1346'), ('name', 'winner')]
#[('p', 'http://www.wikidata.org/entity/Q166177'), ('name', "Ballon d'Or")]
queryString = """
SELECT DISTINCT ?p ?name  ?nname  ?cnname
WHERE {
   # bind something
   wd:Q166177 wdt:P1346 ?p.
   # ?p wdt:P1532 ?n;
       wdt:P27 ?cn.
   # get the label
   # ?p sc:name ?name.
   # ?n sc:name ?nname.
   # ?cn sc:name ?cnname.
   FILTER(?cnname = ?nname)
}
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/entity/Q36386'), ('name', 'Lothar Matthäus'), ('nname', 'Germany'), ('cnname', 'Germany')]
# [('p', 'http://www.wikidata.org/entity/Q483145'), ('name', 'Luís Figo'), ('nname', 'Portugal'), ('cnname', 'Portugal')]
# [('p', 'http://www.wikidata.org/entity/Q39444'), ('name', 'Ronaldinho'), ('nname', 'Brazil'), ('cnname', 'Brazil')]
# [('p', 'http://www.wikidata.org/entity/Q220700'), ('name', 'Omar Sívori'), ('nname', 'Argentina'), ('cnname', 'Argentina')]
# [('p', 'http://www.wikidata.org/entity/Q13494'), ('name', 'Jean-Pierre Papin'), ('nname', 'France'), ('cnname', 'France')]
# [('p', 'http://www.wikidata.org/entity/Q43744'), ('name', 'Gerd Müller'), ('nname', 'Germany'), ('cnname', 'Germany')]
# [('p', 'http://www.wikidata.org/entity/Q152871'), ('name', 'Karl-Heinz Rummenigge'), ('nname', 'Germany'), ('cnname', 'Germany')]
# [('p', 'http://www.wikidata.org/entity/Q1835'), ('name', 'Zinedine Zidane'), ('nname', 'France'), ('cnname', 'France')]
# [('p', 'http://www.wikidata.org/entity/Q531814'), ('name', 'Kaká'), ('nname', 'Brazil'), ('cnname', 'Brazil')]
# [('p', 'http://www.wikidata.org/entity/Q187125'), ('name', 'Hristo Stoichkov'), ('nname', 'Bulgaria'), ('cnname', 'Bulgaria')]
# [('p', 'http://www.wikidata.org/entity/Q615'), ('name', 'Lionel Messi'), ('nname', 'Argentina'), ('cnname', 'Argentina')]
# [('p', 'http://www.wikidata.org/entity/Q11571'), ('name', 'Cristiano Ronaldo'), ('nname', 'Portugal'), ('cnname', 'Portugal')]
# [('p', 'http://www.wikidata.org/entity/Q4457'), ('name', 'Franz Beckenbauer'), ('nname', 'West Germany'), ('cnname', 'West Germany')]
# [('p', 'http://www.wikidata.org/entity/Q164546'), ('name', 'Alfredo Di Stéfano'), ('nname', 'Argentina'), ('cnname', 'Argentina')]
# [('p', 'http://www.wikidata.org/entity/Q529207'), ('name', 'Ronaldo'), ('nname', 'Brazil'), ('cnname', 'Brazil')]
# [('p', 'http://www.wikidata.org/entity/Q57183'), ('name', 'Matthias Sammer'), ('nname', 'Germany'), ('cnname', 'Germany')]
# [('p', 'http://www.wikidata.org/entity/Q102027'), ('name', 'Fabio Cannavaro'), ('nname', 'Italy'), ('cnname', 'Italy')]
# [('p', 'http://www.wikidata.org/entity/Q483837'), ('name', 'Luka Modrić'), ('nname', 'Croatia'), ('cnname', 'Croatia')]
# [('p', 'http://www.wikidata.org/entity/Q4261'), ('name', 'Michel Platini'), ('nname', 'France'), ('cnname', 'France')]
# [('p', 'http://www.wikidata.org/entity/Q41244'), ('name', 'Andriy Shevchenko'), ('nname', 'Ukraine'), ('cnname', 'Ukraine')]
# 20

# %% [markdown]
# Final query for this task

# %%
# write your final query
#[('p', 'http://www.wikidata.org/prop/direct/P1532'), ('name', 'country for sport')]
#[('p', 'http://www.wikidata.org/prop/direct/P27'), ('name', 'country of citizenship')]
#[('p', 'http://www.wikidata.org/prop/direct/P1346'), ('name', 'winner')]
#[('p', 'http://www.wikidata.org/entity/Q166177'), ('name', "Ballon d'Or")]
queryString = """
SELECT DISTINCT (COUNT(distinct ?p) AS ?NumOfPl) ?cnname
WHERE {
   # bind something
   wd:Q166177 wdt:P1346 ?p.
   # ?p wdt:P1532 ?n;
       wdt:P27 ?cn.
   # get the label
   # ?p sc:name ?name.
   # ?n sc:name ?nname.
   # ?cn sc:name ?cnname.
   FILTER(?cnname != ?nname)
}
GROUP BY ?cnname
HAVING (COUNT(distinct ?p) >1)
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('NumOfPl', '6'), ('cnname', 'United Kingdom')]
# [('NumOfPl', '3'), ('cnname', 'Spain')]
# [('NumOfPl', '2'), ('cnname', 'Soviet Union')]
# [('NumOfPl', '2'), ('cnname', 'Kingdom of the Netherlands')]
# [('NumOfPl', '2'), ('cnname', 'Italy')]
# 5

# %% [markdown]
# ## Task 7
# Identify the BGP of the FIFA World Cup

# %%
# Using Ronaldos BGP where he participated in
#[('p', 'http://www.wikidata.org/prop/direct/P1344'), ('name', 'participant in')]
queryString = """
SELECT DISTINCT ?p ?name
WHERE {
   # bind something
   wd:Q11571 wdt:P1344 ?p.
   # get the label
   # ?p sc:name ?name.
}
LIMIT 200
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/entity/Q373501'), ('name', 'UEFA Euro 2020')]
# [('p', 'http://www.wikidata.org/entity/Q102920'), ('name', 'UEFA Euro 2004')]
# [('p', 'http://www.wikidata.org/entity/Q170645'), ('name', '2018 FIFA World Cup')]
# [('p', 'http://www.wikidata.org/entity/Q176883'), ('name', '2010 FIFA World Cup')]
# [('p', 'http://www.wikidata.org/entity/Q189571'), ('name', 'UEFA Euro 2016')]
# [('p', 'http://www.wikidata.org/entity/Q22669'), ('name', 'UEFA Euro 2012')]
# [('p', 'http://www.wikidata.org/entity/Q241864'), ('name', 'UEFA Euro 2008')]
# [('p', 'http://www.wikidata.org/entity/Q324867'), ('name', 'La Liga')]
# [('p', 'http://www.wikidata.org/entity/Q37285'), ('name', '2006 FIFA World Cup')]
# [('p', 'http://www.wikidata.org/entity/Q79859'), ('name', '2014 FIFA World Cup')]
# [('p', 'http://www.wikidata.org/entity/Q8558'), ('name', '2004 Summer Olympics')]
# 11

# %%
#Using 2010 FIFA World Cup ID for exploring
#[('p', 'http://www.wikidata.org/entity/Q176883'), ('name', '2010 FIFA World Cup')]
queryString = """
SELECT DISTINCT ?p ?name
WHERE {
   # bind something
    # ?obj ?p wd:Q176883.
   # get the label
   # ?p sc:name ?name.
}
LIMIT 200
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P1423'), ('name', 'template has topic')]
# [('p', 'http://www.wikidata.org/prop/direct/P6291'), ('name', 'advertises')]
# [('p', 'http://www.wikidata.org/prop/direct/P1269'), ('name', 'facet of')]
# [('p', 'http://www.wikidata.org/prop/direct/P1344'), ('name', 'participant in')]
# [('p', 'http://www.wikidata.org/prop/direct/P1346'), ('name', 'winner')]
# [('p', 'http://www.wikidata.org/prop/direct/P2348'), ('name', 'time period')]
# [('p', 'http://www.wikidata.org/prop/direct/P2522'), ('name', 'victory')]
# [('p', 'http://www.wikidata.org/prop/direct/P301'), ('name', "category's main topic")]
# [('p', 'http://www.wikidata.org/prop/direct/P361'), ('name', 'part of')]
# [('p', 'http://www.wikidata.org/prop/direct/P366'), ('name', 'use')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('name', 'has part')]
# [('p', 'http://www.wikidata.org/prop/direct/P793'), ('name', 'significant event')]
# [('p', 'http://www.wikidata.org/prop/direct/P921'), ('name', 'main subject')]
# [('p', 'http://www.wikidata.org/prop/direct/P971'), ('name', 'category combines topics')]
# [('p', 'http://www.wikidata.org/prop/direct/P1855'), ('name', 'Wikidata property example')]
# 15

# %%
#Using 2010 FIFA World Cup Has Part ID for exploring
#[('p', 'http://www.wikidata.org/entity/Q176883'), ('name', '2010 FIFA World Cup')]
queryString = """
SELECT DISTINCT ?p ?name
WHERE {
   # bind something
    # ?p wdt:P527 wd:Q176883.
   # get the label
   # ?p sc:name ?name.
}
LIMIT 200
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/entity/Q19317'), ('name', 'FIFA World Cup')]
# 1

# %% [markdown]
# Final query for this task

# %%
# write your final query
queryString = """
SELECT DISTINCT ?p ?name
WHERE {
   # bind something
   wd:Q19317 ?p ?obj.
   # get the label
   # ?p sc:name ?name.
}
LIMIT 200
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P7441'), ('name', 'WorldFootball.net competition ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1015'), ('name', 'NORAF ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1151'), ('name', "topic's main Wikimedia portal")]
# [('p', 'http://www.wikidata.org/prop/direct/P1296'), ('name', 'Gran Enciclopèdia Catalana ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1417'), ('name', 'Encyclopædia Britannica Online ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1424'), ('name', "topic's main template")]
# [('p', 'http://www.wikidata.org/prop/direct/P1705'), ('name', 'native label')]
# [('p', 'http://www.wikidata.org/prop/direct/P18'), ('name', 'image')]
# [('p', 'http://www.wikidata.org/prop/direct/P2002'), ('name', 'Twitter username')]
# [('p', 'http://www.wikidata.org/prop/direct/P2003'), ('name', 'Instagram username')]
# [('p', 'http://www.wikidata.org/prop/direct/P2013'), ('name', 'Facebook ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2094'), ('name', 'competition class')]
# [('p', 'http://www.wikidata.org/prop/direct/P214'), ('name', 'VIAF ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2184'), ('name', 'history of topic')]
# [('p', 'http://www.wikidata.org/prop/direct/P2257'), ('name', 'event interval')]
# [('p', 'http://www.wikidata.org/prop/direct/P227'), ('name', 'GND ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2397'), ('name', 'YouTube channel ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P244'), ('name', 'Library of Congress authority ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2922'), ('name', 'month of the year')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('name', 'instance of')]
# [('p', 'http://www.wikidata.org/prop/direct/P3219'), ('name', 'Encyclopædia Universalis ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3221'), ('name', 'New York Times topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3417'), ('name', 'Quora topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P373'), ('name', 'Commons category')]
# [('p', 'http://www.wikidata.org/prop/direct/P3984'), ('name', 'subreddit')]
# [('p', 'http://www.wikidata.org/prop/direct/P4527'), ('name', 'UK Parliament thesaurus ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('name', 'has part')]
# [('p', 'http://www.wikidata.org/prop/direct/P571'), ('name', 'inception')]
# [('p', 'http://www.wikidata.org/prop/direct/P6262'), ('name', 'Fandom article ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P641'), ('name', 'sport')]
# [('p', 'http://www.wikidata.org/prop/direct/P646'), ('name', 'Freebase ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6573'), ('name', 'Klexikon article ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P664'), ('name', 'organizer')]
# [('p', 'http://www.wikidata.org/prop/direct/P691'), ('name', 'NKCR AUT ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7859'), ('name', 'WorldCat Identities ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8408'), ('name', 'KBpedia ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P856'), ('name', 'official website')]
# [('p', 'http://www.wikidata.org/prop/direct/P8687'), ('name', 'social media followers')]
# [('p', 'http://www.wikidata.org/prop/direct/P910'), ('name', "topic's main category")]
# [('p', 'http://www.wikidata.org/prop/direct/P9322'), ('name', 'SVKKL authority ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P949'), ('name', 'National Library of Israel ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2517'), ('name', 'category for recipients of this award')]
# [('p', 'http://www.wikidata.org/prop/direct/P3579'), ('name', 'Sina Weibo user ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8735'), ('name', 'Opta football competition ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8115'), ('name', 'eligible recipient')]
# 45

# %% [markdown]
# ## Task 8
# Who are the players who partecipated in more than 4 world's cup editions? (the result set must be a list of triples player IRI, label and #participations).

# %%
#Using 2010 FIFA World Cup ID for exploring
#[('p', 'http://www.wikidata.org/entity/Q176883'), ('name', '2010 FIFA World Cup')]
queryString = """
SELECT DISTINCT ?p ?name
WHERE {
   # bind something
    wd:Q176883 ?p ?obj .
   # get the label
   # ?p sc:name ?name.
}
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P4967'), ('name', 'prerequisite')]
# [('p', 'http://www.wikidata.org/prop/direct/P1132'), ('name', 'number of participants')]
# [('p', 'http://www.wikidata.org/prop/direct/P1346'), ('name', 'winner')]
# [('p', 'http://www.wikidata.org/prop/direct/P1350'), ('name', 'number of matches played/races/starts')]
# [('p', 'http://www.wikidata.org/prop/direct/P1424'), ('name', "topic's main template")]
# [('p', 'http://www.wikidata.org/prop/direct/P17'), ('name', 'country')]
# [('p', 'http://www.wikidata.org/prop/direct/P18'), ('name', 'image')]
# [('p', 'http://www.wikidata.org/prop/direct/P2094'), ('name', 'competition class')]
# [('p', 'http://www.wikidata.org/prop/direct/P214'), ('name', 'VIAF ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P227'), ('name', 'GND ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P244'), ('name', 'Library of Congress authority ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2581'), ('name', 'BabelNet ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P276'), ('name', 'location')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('name', 'instance of')]
# [('p', 'http://www.wikidata.org/prop/direct/P3417'), ('name', 'Quora topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3450'), ('name', 'sports season of league or competition')]
# [('p', 'http://www.wikidata.org/prop/direct/P373'), ('name', 'Commons category')]
# [('p', 'http://www.wikidata.org/prop/direct/P393'), ('name', 'edition number')]
# [('p', 'http://www.wikidata.org/prop/direct/P3967'), ('name', 'final event')]
# [('p', 'http://www.wikidata.org/prop/direct/P454'), ('name', 'Structurae structure ID')]
# 20

# %%
#Exploring Teams Participated for getting teams
queryString = """
SELECT DISTINCT ?p ?name
WHERE {
   # bind something
    wd:Q176883 wdt:P1923 ?p.
    
   # get the label
   # ?p sc:name ?name.
}
LIMIT 200
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/entity/Q676899'), ('name', 'Italy national association football team')]
# [('p', 'http://www.wikidata.org/entity/Q268208'), ('name', 'Australia national association football team')]
# [('p', 'http://www.wikidata.org/entity/Q134916'), ('name', 'Uruguay national football team')]
# [('p', 'http://www.wikidata.org/entity/Q170327'), ('name', 'South Africa national football team')]
# [('p', 'http://www.wikidata.org/entity/Q14132'), ('name', 'North Korea national football team')]
# [('p', 'http://www.wikidata.org/entity/Q174512'), ('name', 'Slovakia national association football team')]
# [('p', 'http://www.wikidata.org/entity/Q175145'), ('name', 'Ivory Coast national football team')]
# [('p', 'http://www.wikidata.org/entity/Q180187'), ('name', 'Honduras national football team')]
# [('p', 'http://www.wikidata.org/entity/Q172221'), ('name', 'Slovenia national football team')]
# [('p', 'http://www.wikidata.org/entity/Q47050'), ('name', 'Netherlands national association football team')]
# [('p', 'http://www.wikidata.org/entity/Q47762'), ('name', 'England national association football team')]
# [('p', 'http://www.wikidata.org/entity/Q47774'), ('name', 'France national association football team')]
# [('p', 'http://www.wikidata.org/entity/Q182740'), ('name', 'Serbia national football team')]
# [('p', 'http://www.wikidata.org/entity/Q42267'), ('name', 'Spain national association football team')]
# [('p', 'http://www.wikidata.org/entity/Q79800'), ('name', 'Argentina national football team')]
# [('p', 'http://www.wikidata.org/entity/Q83459'), ('name', 'Brazil national football team')]
# [('p', 'http://www.wikidata.org/entity/Q172020'), ('name', 'Paraguay national football team')]
# [('p', 'http://www.wikidata.org/entity/Q181903'), ('name', 'Algeria national football team')]
# [('p', 'http://www.wikidata.org/entity/Q181930'), ('name', 'Nigeria national football team')]
# [('p', 'http://www.wikidata.org/entity/Q267245'), ('name', 'Portugal national association football team')]
# [('p', 'http://www.wikidata.org/entity/Q43310'), ('name', 'Germany national association football team')]
# [('p', 'http://www.wikidata.org/entity/Q164089'), ('name', 'Mexico national football team')]
# [('p', 'http://www.wikidata.org/entity/Q131785'), ('name', 'Denmark national association football team')]
# [('p', 'http://www.wikidata.org/entity/Q134925'), ('name', 'Greece national association football team')]
# [('p', 'http://www.wikidata.org/entity/Q164134'), ('name', "United States men's national soccer team")]
# [('p', 'http://www.wikidata.org/entity/Q165141'), ('name', 'Swiss national football team')]
# [('p', 'http://www.wikidata.org/entity/Q175309'), ('name', 'Cameroon national football team')]
# [('p', 'http://www.wikidata.org/entity/Q543842'), ('name', 'South Korea national football team')]
# [('p', 'http://www.wikidata.org/entity/Q170566'), ('name', 'Japan national football team')]
# [('p', 'http://www.wikidata.org/entity/Q172014'), ('name', 'Ghana national football team')]
# [('p', 'http://www.wikidata.org/entity/Q172025'), ('name', 'Chile national football team')]
# [('p', 'http://www.wikidata.org/entity/Q175315'), ('name', 'New Zealand national football team')]
# 32

# %%
#Getting Teams for All WCs

queryString = """
SELECT DISTINCT ?p ?name
WHERE {
   # bind something
   wd:Q19317 wdt:P527 ?t.
    # ?t wdt:P1923 ?p.
    
   # get the label
   # ?p sc:name ?name.
}
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/entity/Q166196'), ('name', 'Poland national association football team')]
# [('p', 'http://www.wikidata.org/entity/Q168397'), ('name', 'Romania national association football team')]
# [('p', 'http://www.wikidata.org/entity/Q676899'), ('name', 'Italy national association football team')]
# [('p', 'http://www.wikidata.org/entity/Q163534'), ('name', 'Austria national association football team')]
# [('p', 'http://www.wikidata.org/entity/Q212564'), ('name', 'Colombia national football team')]
# [('p', 'http://www.wikidata.org/entity/Q268208'), ('name', 'Australia national association football team')]
# [('p', 'http://www.wikidata.org/entity/Q134916'), ('name', 'Uruguay national football team')]
# [('p', 'http://www.wikidata.org/entity/Q181190'), ('name', 'Bosnia and Herzegovina national football team')]
# [('p', 'http://www.wikidata.org/entity/Q170327'), ('name', 'South Africa national football team')]
# [('p', 'http://www.wikidata.org/entity/Q186243'), ('name', 'Iraq national football team')]
# [('p', 'http://www.wikidata.org/entity/Q191406'), ('name', 'Israel national football team')]
# [('p', 'http://www.wikidata.org/entity/Q14132'), ('name', 'North Korea national football team')]
# [('p', 'http://www.wikidata.org/entity/Q170403'), ('name', 'Ukraine national association football team')]
# [('p', 'http://www.wikidata.org/entity/Q174512'), ('name', 'Slovakia national association football team')]
# [('p', 'http://www.wikidata.org/entity/Q175145'), ('name', 'Ivory Coast national football team')]
# [('p', 'http://www.wikidata.org/entity/Q180187'), ('name', 'Honduras national football team')]
# [('p', 'http://www.wikidata.org/entity/Q180857'), ('name', 'Wales national association football team')]
# [('p', 'http://www.wikidata.org/entity/Q270080'), ('name', 'DR Congo national football team')]
# [('p', 'http://www.wikidata.org/entity/Q130582'), ('name', 'China national football team')]
# [('p', 'http://www.wikidata.org/entity/Q194387'), ('name', 'Costa Rica national football team')]
# 20

# %%
#Exploring one country for relation to players
#[('p', 'http://www.wikidata.org/entity/Q676899'), ('name', 'Italy national association football team')]
queryString = """
SELECT DISTINCT ?p ?name ?pl ?plname
WHERE {
   # bind something
    # ?pl ?p wd:Q676899.
    
    
   # get the label
   # ?p sc:name ?name.
   # ?pl sc:name ?plname
}
LIMIT 2
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P1346'), ('name', 'winner'), ('pl', 'http://www.wikidata.org/entity/Q706023'), ('plname', '2004 UEFA European Under-21 Football Championship')]
# [('p', 'http://www.wikidata.org/prop/direct/P54'), ('name', 'member of sports team'), ('pl', 'http://www.wikidata.org/entity/Q1875825'), ('plname', 'Guido Corbelli')]
# 2

# %%
#Exploring one country for relation to players
#[('p', 'http://www.wikidata.org/entity/Q676899'), ('name', 'Italy national association football team')]
queryString = """
SELECT DISTINCT  ?pl ?plname
WHERE {
   # bind something
    # ?pl wdt:P54 wd:Q676899.
    
    
   # get the label
   #?p sc:name ?name.
   # ?pl sc:name ?plname
}
LIMIT 2

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('pl', 'http://www.wikidata.org/entity/Q1875825'), ('plname', 'Guido Corbelli')]
# [('pl', 'http://www.wikidata.org/entity/Q3092596'), ('plname', 'Felice Romano')]
# 2

# %%
#Adding relation member of sports team

queryString = """
SELECT DISTINCT ?p ?name ?pl ?plname ?t ?tname
WHERE {
   # bind something
   wd:Q19317 wdt:P527 ?t.
    # ?t wdt:P1923 ?p.
     # ?pl wdt:P54 ?p.
         
    
   # get the label
   # ?p sc:name ?name.
   # ?pl sc:name ?plname.
   # ?t sc:name ?tname.
      FILTER(REGEX(?plname,"Lionel Messi"^^xsd:string))

}
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/entity/Q79800'), ('name', 'Argentina national football team'), ('pl', 'http://www.wikidata.org/entity/Q615'), ('plname', 'Lionel Messi'), ('t', 'http://www.wikidata.org/entity/Q101751'), ('tname', '1994 FIFA World Cup')]
# [('p', 'http://www.wikidata.org/entity/Q79800'), ('name', 'Argentina national football team'), ('pl', 'http://www.wikidata.org/entity/Q615'), ('plname', 'Lionel Messi'), ('t', 'http://www.wikidata.org/entity/Q48432'), ('tname', '1930 FIFA World Cup')]
# [('p', 'http://www.wikidata.org/entity/Q79800'), ('name', 'Argentina national football team'), ('pl', 'http://www.wikidata.org/entity/Q615'), ('plname', 'Lionel Messi'), ('t', 'http://www.wikidata.org/entity/Q176883'), ('tname', '2010 FIFA World Cup')]
# [('p', 'http://www.wikidata.org/entity/Q79800'), ('name', 'Argentina national football team'), ('pl', 'http://www.wikidata.org/entity/Q615'), ('plname', 'Lionel Messi'), ('t', 'http://www.wikidata.org/entity/Q46938'), ('tname', '1986 FIFA World Cup')]
# [('p', 'http://www.wikidata.org/entity/Q79800'), ('name', 'Argentina national football team'), ('pl', 'http://www.wikidata.org/entity/Q615'), ('plname', 'Lionel Messi'), ('t', 'http://www.wikidata.org/entity/Q47735'), ('tname', '2002 FIFA World Cup')]
# [('p', 'http://www.wikidata.org/entity/Q79800'), ('name', 'Argentina national football team'), ('pl', 'http://www.wikidata.org/entity/Q615'), ('plname', 'Lionel Messi'), ('t', 'http://www.wikidata.org/entity/Q46943'), ('tname', '1978 FIFA World Cup')]
# [('p', 'http://www.wikidata.org/entity/Q79800'), ('name', 'Argentina national football team'), ('pl', 'http://www.wikidata.org/entity/Q615'), ('plname', 'Lionel Messi'), ('t', 'http://www.wikidata.org/entity/Q79859'), ('tname', '2014 FIFA World Cup')]
# [('p', 'http://www.wikidata.org/entity/Q79800'), ('name', 'Argentina national football team'), ('pl', 'http://www.wikidata.org/entity/Q615'), ('plname', 'Lionel Messi'), ('t', 'http://www.wikidata.org/entity/Q37285'), ('tname', '2006 FIFA World Cup')]
# [('p', 'http://www.wikidata.org/entity/Q79800'), ('name', 'Argentina national football team'), ('pl', 'http://www.wikidata.org/entity/Q615'), ('plname', 'Lionel Messi'), ('t', 'http://www.wikidata.org/entity/Q46934'), ('tname', '1982 FIFA World Cup')]
# [('p', 'http://www.wikidata.org/entity/Q79800'), ('name', 'Argentina national football team'), ('pl', 'http://www.wikidata.org/entity/Q615'), ('plname', 'Lionel Messi'), ('t', 'http://www.wikidata.org/entity/Q132529'), ('tname', '1990 FIFA World Cup')]
# [('p', 'http://www.wikidata.org/entity/Q79800'), ('name', 'Argentina national football team'), ('pl', 'http://www.wikidata.org/entity/Q615'), ('plname', 'Lionel Messi'), ('t', 'http://www.wikidata.org/entity/Q101730'), ('tname', '1998 FIFA World Cup')]
# [('p', 'http://www.wikidata.org/entity/Q79800'), ('name', 'Argentina national football team'), ('pl', 'http://www.wikidata.org/entity/Q615'), ('plname', 'Lionel Messi'), ('t', 'http://www.wikidata.org/entity/Q134202'), ('tname', '1966 FIFA World Cup')]
# [('p', 'http://www.wikidata.org/entity/Q79800'), ('name', 'Argentina national football team'), ('pl', 'http://www.wikidata.org/entity/Q615'), ('plname', 'Lionel Messi'), ('t', 'http://www.wikidata.org/entity/Q1477177'), ('tname', '1934 FIFA World Cup')]
# [('p', 'http://www.wikidata.org/entity/Q79800'), ('name', 'Argentina national football team'), ('pl', 'http://www.wikidata.org/entity/Q615'), ('plname', 'Lionel Messi'), ('t', 'http://www.wikidata.org/entity/Q132533'), ('tname', '1958 FIFA World Cup')]
# [('p', 'http://www.wikidata.org/entity/Q79800'), ('name', 'Argentina national football team'), ('pl', 'http://www.wikidata.org/entity/Q615'), ('plname', 'Lionel Messi'), ('t', 'http://www.wikidata.org/entity/Q160813'), ('tname', '1962 FIFA World Cup')]
# [('p', 'http://www.wikidata.org/entity/Q79800'), ('name', 'Argentina national football team'), ('pl', 'http://www.wikidata.org/entity/Q615'), ('plname', 'Lionel Messi'), ('t', 'http://www.wikidata.org/entity/Q166121'), ('tname', '1974 FIFA World Cup')]
# 16

# %%
#Getting Teams for All WCs

queryString = """
SELECT DISTINCT (COUNT(?t) as ?NumOfWC) ?pl ?plname
WHERE {
   # bind something
   wd:Q19317 wdt:P527 ?t.
    # ?t wdt:P1923 ?p.
     # ?pl wdt:P54 ?p.
         
    
   # get the label
   # ?p sc:name ?name.
   # ?pl sc:name ?plname
   FILTER(REGEX(?plname,"Messi"^^xsd:string))
}
GROUP BY ?plname ?pl
ORDER BY DESC(?NumOfWC)
LIMIT 200

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('NumOfWC', '16'), ('pl', 'http://www.wikidata.org/entity/Q615'), ('plname', 'Lionel Messi')]
# [('NumOfWC', '8'), ('pl', 'http://www.wikidata.org/entity/Q17364536'), ('plname', 'Bruno Valdez Messi')]
# [('NumOfWC', '6'), ('pl', 'http://www.wikidata.org/entity/Q3307048'), ('plname', 'Messias Timula')]
# [('NumOfWC', '2'), ('pl', 'http://www.wikidata.org/entity/Q9028594'), ('plname', 'Marcelo Messias')]
# 4

# %%
#Probably a Wrong / difficult Approach to filter out players as we see that Query is finding number of worldcups by each time and regardless if he played worldcup or not his name is displayed
#Using Football Association Player ID to use the other approach
# BGP of Association Football Player
queryString = """
SELECT DISTINCT ?p ?name
WHERE {
   # bind something
   wd:Q937857 ?obj ?p.
   # get the label
   # ?p sc:name ?name.
}
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/entity/P2369'), ('name', 'Soccerway player ID')]
# [('p', 'http://www.wikidata.org/entity/P3908'), ('name', 'Reprezentacija player ID')]
# [('p', 'http://www.wikidata.org/entity/Q18536342'), ('name', 'competitive player')]
# [('p', 'http://www.wikidata.org/entity/P2446'), ('name', 'Transfermarkt player ID')]
# [('p', 'http://www.wikidata.org/entity/Q7217464'), ('name', 'Category:Association football players')]
# [('p', 'http://www.wikidata.org/entity/P2823'), ('name', 'Royal Belgian Football Association player ID')]
# [('p', 'http://www.wikidata.org/entity/Q15944511'), ('name', 'association football team')]
# [('p', 'http://www.wikidata.org/entity/Q2736'), ('name', 'association football')]
# [('p', 'http://www.wikidata.org/entity/Q28640'), ('name', 'profession')]
# [('p', 'http://www.wikidata.org/entity/Q476028'), ('name', 'association football club')]
# [('p', 'http://www.wikidata.org/entity/Q31930761'), ('name', "men's association football")]
# [('p', 'http://www.wikidata.org/entity/Q17019799'), ('name', 'Template:SD Eibar squad')]
# [('p', 'http://www.wikidata.org/entity/Q2066131'), ('name', 'athlete')]
# [('p', 'http://www.wikidata.org/entity/Q606060'), ('name', "women's association football")]
# [('p', 'http://www.wikidata.org/entity/P1469'), ('name', 'FIFA player ID')]
# [('p', 'http://www.wikidata.org/entity/P4019'), ('name', 'USL Championship player ID')]
# [('p', 'http://www.wikidata.org/entity/P2574'), ('name', 'National-Football-Teams.com player ID')]
# [('p', 'http://www.wikidata.org/entity/Q6690764'), ('name', 'Template:Atlético Madrid squad')]
# [('p', 'http://www.wikidata.org/entity/Q1381731'), ('name', 'kit')]
# [('p', 'http://www.wikidata.org/entity/P3677'), ('name', 'Wereld van Oranje player ID')]
# 20

# %%
#Getting FIFA Player ID
#[('p', 'http://www.wikidata.org/entity/P1469'), ('name', 'FIFA player ID')]
queryString = """
SELECT DISTINCT ?p ?name ?pl ?pname
WHERE {
   # bind something
    # ?p wdt:P1469 ?obj;
        wdt:P1344 ?pl.
   # get the label
   # ?p sc:name ?name.
   # ?pl sc:name ?pname.
   FILTER(REGEX(?pname,"FIFA World Cup$"^^xsd:string))
}
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/entity/Q1652615'), ('name', 'Paul Caligiuri'), ('pl', 'http://www.wikidata.org/entity/Q101751'), ('pname', '1994 FIFA World Cup')]
# [('p', 'http://www.wikidata.org/entity/Q261069'), ('name', 'Stig Inge Bjørnebye'), ('pl', 'http://www.wikidata.org/entity/Q101751'), ('pname', '1994 FIFA World Cup')]
# [('p', 'http://www.wikidata.org/entity/Q448678'), ('name', 'Trifon Ivanov'), ('pl', 'http://www.wikidata.org/entity/Q101751'), ('pname', '1994 FIFA World Cup')]
# [('p', 'http://www.wikidata.org/entity/Q178649'), ('name', 'Romário'), ('pl', 'http://www.wikidata.org/entity/Q101751'), ('pname', '1994 FIFA World Cup')]
# [('p', 'http://www.wikidata.org/entity/Q486648'), ('name', 'Gu Sang-bum'), ('pl', 'http://www.wikidata.org/entity/Q101751'), ('pname', '1994 FIFA World Cup')]
# [('p', 'http://www.wikidata.org/entity/Q486937'), ('name', 'Choi In-young'), ('pl', 'http://www.wikidata.org/entity/Q101751'), ('pname', '1994 FIFA World Cup')]
# [('p', 'http://www.wikidata.org/entity/Q496138'), ('name', 'Park Jung-bae'), ('pl', 'http://www.wikidata.org/entity/Q101751'), ('pname', '1994 FIFA World Cup')]
# [('p', 'http://www.wikidata.org/entity/Q503297'), ('name', 'Tarcisio Burgnich'), ('pl', 'http://www.wikidata.org/entity/Q132664'), ('pname', '1970 FIFA World Cup')]
# [('p', 'http://www.wikidata.org/entity/Q503421'), ('name', 'Alain Sutter'), ('pl', 'http://www.wikidata.org/entity/Q101751'), ('pname', '1994 FIFA World Cup')]
# [('p', 'http://www.wikidata.org/entity/Q532393'), ('name', 'Borislav Mikhailov'), ('pl', 'http://www.wikidata.org/entity/Q101751'), ('pname', '1994 FIFA World Cup')]
# [('p', 'http://www.wikidata.org/entity/Q539964'), ('name', 'Abdelkrim El Hadrioui'), ('pl', 'http://www.wikidata.org/entity/Q101751'), ('pname', '1994 FIFA World Cup')]
# [('p', 'http://www.wikidata.org/entity/Q552710'), ('name', 'Dmitri Kharine'), ('pl', 'http://www.wikidata.org/entity/Q101751'), ('pname', '1994 FIFA World Cup')]
# [('p', 'http://www.wikidata.org/entity/Q552767'), ('name', 'John Sheridan'), ('pl', 'http://www.wikidata.org/entity/Q101751'), ('pname', '1994 FIFA World Cup')]
# [('p', 'http://www.wikidata.org/entity/Q654644'), ('name', 'Petar Aleksandrov'), ('pl', 'http://www.wikidata.org/entity/Q101751'), ('pname', '1994 FIFA World Cup')]
# [('p', 'http://www.wikidata.org/entity/Q658112'), ('name', 'Horst Wolter'), ('pl', 'http://www.wikidata.org/entity/Q132664'), ('pname', '1970 FIFA World Cup')]
# [('p', 'http://www.wikidata.org/entity/Q671196'), ('name', 'Marc Hottiger'), ('pl', 'http://www.wikidata.org/entity/Q101751'), ('pname', '1994 FIFA World Cup')]
# [('p', 'http://www.wikidata.org/entity/Q1855723'), ('name', 'Vintilă Cossini'), ('pl', 'http://www.wikidata.org/entity/Q131591'), ('pname', '1938 FIFA World Cup')]
# [('p', 'http://www.wikidata.org/entity/Q1856693'), ('name', 'Niek Michel'), ('pl', 'http://www.wikidata.org/entity/Q131591'), ('pname', '1938 FIFA World Cup')]
# [('p', 'http://www.wikidata.org/entity/Q191492'), ('name', 'Bobby Moore'), ('pl', 'http://www.wikidata.org/entity/Q132664'), ('pname', '1970 FIFA World Cup')]
# [('p', 'http://www.wikidata.org/entity/Q2535926'), ('name', 'Eddie McGoldrick'), ('pl', 'http://www.wikidata.org/entity/Q101751'), ('pname', '1994 FIFA World Cup')]
# 20

# %%
#Counting Appearance of players
#[('p', 'http://www.wikidata.org/entity/P1469'), ('name', 'FIFA player ID')]
queryString = """
SELECT DISTINCT ?p ?name (COUNT(distinct ?pl) AS ?NumOfWC)
WHERE {
   # bind something
    # ?p wdt:P1469 ?obj;
        wdt:P1344 ?pl.
   # get the label
   # ?p sc:name ?name.
   # ?pl sc:name ?pname.
   FILTER(REGEX(?pname,"FIFA World Cup$"^^xsd:string))
}
GROUP BY ?p ?name 
ORDER BY DESC(?NumOfWC)
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/entity/Q186330'), ('name', 'Rafael Márquez'), ('NumOfWC', '5')]
# [('p', 'http://www.wikidata.org/entity/Q265428'), ('name', 'Antonio Carbajal'), ('NumOfWC', '5')]
# [('p', 'http://www.wikidata.org/entity/Q36386'), ('name', 'Lothar Matthäus'), ('NumOfWC', '5')]
# [('p', 'http://www.wikidata.org/entity/Q68060'), ('name', 'Gianluigi Buffon'), ('NumOfWC', '5')]
# [('p', 'http://www.wikidata.org/entity/Q299693'), ('name', 'Djalma Santos'), ('NumOfWC', '4')]
# [('p', 'http://www.wikidata.org/entity/Q274872'), ('name', 'Émerson Leão'), ('NumOfWC', '4')]
# [('p', 'http://www.wikidata.org/entity/Q161571'), ('name', 'Javier Mascherano'), ('NumOfWC', '4')]
# [('p', 'http://www.wikidata.org/entity/Q80471'), ('name', 'Miroslav Klose'), ('NumOfWC', '4')]
# [('p', 'http://www.wikidata.org/entity/Q312179'), ('name', 'Mohamed Al-Deayea'), ('NumOfWC', '4')]
# [('p', 'http://www.wikidata.org/entity/Q313035'), ('name', 'DaMarcus Beasley'), ('NumOfWC', '4')]
# [('p', 'http://www.wikidata.org/entity/Q459778'), ('name', 'Enrico Albertosi'), ('NumOfWC', '4')]
# [('p', 'http://www.wikidata.org/entity/Q60435'), ('name', 'Karl-Heinz Schnellinger'), ('NumOfWC', '4')]
# [('p', 'http://www.wikidata.org/entity/Q346718'), ('name', 'Denis Caniza'), ('NumOfWC', '4')]
# [('p', 'http://www.wikidata.org/entity/Q529207'), ('name', 'Ronaldo'), ('NumOfWC', '4')]
# [('p', 'http://www.wikidata.org/entity/Q208550'), ('name', 'Yoshikatsu Kawaguchi'), ('NumOfWC', '4')]
# [('p', 'http://www.wikidata.org/entity/Q299555'), ('name', 'Sami Al-Jaber'), ('NumOfWC', '4')]
# [('p', 'http://www.wikidata.org/entity/Q235159'), ('name', 'Giuseppe Bergomi'), ('NumOfWC', '4')]
# [('p', 'http://www.wikidata.org/entity/Q83329'), ('name', 'Nílton Santos'), ('NumOfWC', '4')]
# [('p', 'http://www.wikidata.org/entity/Q460521'), ('name', "Jacques Songo'o"), ('NumOfWC', '4')]
# [('p', 'http://www.wikidata.org/entity/Q171583'), ('name', 'Bobby Charlton'), ('NumOfWC', '4')]
# 20

# %% [markdown]
# Final query for this task

# %%
# write your final query
#Players Who Participated in more than 4 World Cups (Data doesnot include 2022 Worldcup)
#Counting Appearance of players
#[('p', 'http://www.wikidata.org/entity/P1469'), ('name', 'FIFA player ID')]
queryString = """
SELECT DISTINCT ?p ?name (COUNT(distinct ?pl) AS ?NumOfWC)
WHERE {
   # bind something
    # ?p wdt:P1469 ?obj;
        wdt:P1344 ?pl.
   # get the label
   # ?p sc:name ?name.
   # ?pl sc:name ?pname.
   FILTER(REGEX(?pname,"FIFA World Cup$"^^xsd:string))
}
GROUP BY ?p ?name 
HAVING (COUNT(distinct ?pl) > 4)
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/entity/Q186330'), ('name', 'Rafael Márquez'), ('NumOfWC', '5')]
# [('p', 'http://www.wikidata.org/entity/Q265428'), ('name', 'Antonio Carbajal'), ('NumOfWC', '5')]
# [('p', 'http://www.wikidata.org/entity/Q36386'), ('name', 'Lothar Matthäus'), ('NumOfWC', '5')]
# [('p', 'http://www.wikidata.org/entity/Q68060'), ('name', 'Gianluigi Buffon'), ('NumOfWC', '5')]
# 4

# %% [markdown]
# ## Task 9
# Consider the countries that won the FIFA World Cup at least twice. Find the players of those countries won the ballon d'Or (the result set must be a list of couples player IRI and label).

# %%
# Using FIFA WC BGP to explore
queryString = """
SELECT DISTINCT ?p ?name
WHERE {
   # bind something
   wd:Q19317 wdt:P527 ?p.
   # get the label
   # ?p sc:name ?name.
}
ORDER BY ASC(?name)
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/entity/Q48432'), ('name', '1930 FIFA World Cup')]
# [('p', 'http://www.wikidata.org/entity/Q1477177'), ('name', '1934 FIFA World Cup')]
# [('p', 'http://www.wikidata.org/entity/Q131591'), ('name', '1938 FIFA World Cup')]
# [('p', 'http://www.wikidata.org/entity/Q203851'), ('name', '1942 FIFA World Cup')]
# [('p', 'http://www.wikidata.org/entity/Q65273310'), ('name', '1946 FIFA World Cup')]
# [('p', 'http://www.wikidata.org/entity/Q132515'), ('name', '1950 FIFA World Cup')]
# [('p', 'http://www.wikidata.org/entity/Q131075'), ('name', '1954 FIFA World Cup')]
# [('p', 'http://www.wikidata.org/entity/Q132533'), ('name', '1958 FIFA World Cup')]
# [('p', 'http://www.wikidata.org/entity/Q160813'), ('name', '1962 FIFA World Cup')]
# [('p', 'http://www.wikidata.org/entity/Q134202'), ('name', '1966 FIFA World Cup')]
# [('p', 'http://www.wikidata.org/entity/Q132664'), ('name', '1970 FIFA World Cup')]
# [('p', 'http://www.wikidata.org/entity/Q166121'), ('name', '1974 FIFA World Cup')]
# [('p', 'http://www.wikidata.org/entity/Q46943'), ('name', '1978 FIFA World Cup')]
# [('p', 'http://www.wikidata.org/entity/Q46934'), ('name', '1982 FIFA World Cup')]
# [('p', 'http://www.wikidata.org/entity/Q46938'), ('name', '1986 FIFA World Cup')]
# [('p', 'http://www.wikidata.org/entity/Q132529'), ('name', '1990 FIFA World Cup')]
# [('p', 'http://www.wikidata.org/entity/Q101751'), ('name', '1994 FIFA World Cup')]
# [('p', 'http://www.wikidata.org/entity/Q101730'), ('name', '1998 FIFA World Cup')]
# [('p', 'http://www.wikidata.org/entity/Q47735'), ('name', '2002 FIFA World Cup')]
# [('p', 'http://www.wikidata.org/entity/Q37285'), ('name', '2006 FIFA World Cup')]
# 20

# %%
#We know from Task 7 we have winner in each FIFA WC
#[('p', 'http://www.wikidata.org/prop/direct/P1346'), ('name', 'winner')]
queryString = """
SELECT DISTINCT ?p ?name ?c ?cname
WHERE {
   # bind something
   wd:Q19317 wdt:P527 ?p.
   # ?p wdt:P1346 ?c.
   # get the label
   # ?p sc:name ?name.
   # ?c sc:name ?cname.
}
ORDER BY ASC(?name)
LIMIT 200
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/entity/Q48432'), ('name', '1930 FIFA World Cup'), ('c', 'http://www.wikidata.org/entity/Q134916'), ('cname', 'Uruguay national football team')]
# [('p', 'http://www.wikidata.org/entity/Q1477177'), ('name', '1934 FIFA World Cup'), ('c', 'http://www.wikidata.org/entity/Q676899'), ('cname', 'Italy national association football team')]
# [('p', 'http://www.wikidata.org/entity/Q131591'), ('name', '1938 FIFA World Cup'), ('c', 'http://www.wikidata.org/entity/Q676899'), ('cname', 'Italy national association football team')]
# [('p', 'http://www.wikidata.org/entity/Q132515'), ('name', '1950 FIFA World Cup'), ('c', 'http://www.wikidata.org/entity/Q134916'), ('cname', 'Uruguay national football team')]
# [('p', 'http://www.wikidata.org/entity/Q131075'), ('name', '1954 FIFA World Cup'), ('c', 'http://www.wikidata.org/entity/Q43310'), ('cname', 'Germany national association football team')]
# [('p', 'http://www.wikidata.org/entity/Q132533'), ('name', '1958 FIFA World Cup'), ('c', 'http://www.wikidata.org/entity/Q83459'), ('cname', 'Brazil national football team')]
# [('p', 'http://www.wikidata.org/entity/Q160813'), ('name', '1962 FIFA World Cup'), ('c', 'http://www.wikidata.org/entity/Q83459'), ('cname', 'Brazil national football team')]
# [('p', 'http://www.wikidata.org/entity/Q134202'), ('name', '1966 FIFA World Cup'), ('c', 'http://www.wikidata.org/entity/Q47762'), ('cname', 'England national association football team')]
# [('p', 'http://www.wikidata.org/entity/Q132664'), ('name', '1970 FIFA World Cup'), ('c', 'http://www.wikidata.org/entity/Q83459'), ('cname', 'Brazil national football team')]
# [('p', 'http://www.wikidata.org/entity/Q166121'), ('name', '1974 FIFA World Cup'), ('c', 'http://www.wikidata.org/entity/Q43310'), ('cname', 'Germany national association football team')]
# [('p', 'http://www.wikidata.org/entity/Q46943'), ('name', '1978 FIFA World Cup'), ('c', 'http://www.wikidata.org/entity/Q79800'), ('cname', 'Argentina national football team')]
# [('p', 'http://www.wikidata.org/entity/Q46934'), ('name', '1982 FIFA World Cup'), ('c', 'http://www.wikidata.org/entity/Q676899'), ('cname', 'Italy national association football team')]
# [('p', 'http://www.wikidata.org/entity/Q46938'), ('name', '1986 FIFA World Cup'), ('c', 'http://www.wikidata.org/entity/Q79800'), ('cname', 'Argentina national football team')]
# [('p', 'http://www.wikidata.org/entity/Q132529'), ('name', '1990 FIFA World Cup'), ('c', 'http://www.wikidata.org/entity/Q43310'), ('cname', 'Germany national association football team')]
# [('p', 'http://www.wikidata.org/entity/Q101751'), ('name', '1994 FIFA World Cup'), ('c', 'http://www.wikidata.org/entity/Q83459'), ('cname', 'Brazil national football team')]
# [('p', 'http://www.wikidata.org/entity/Q101730'), ('name', '1998 FIFA World Cup'), ('c', 'http://www.wikidata.org/entity/Q47774'), ('cname', 'France national association football team')]
# [('p', 'http://www.wikidata.org/entity/Q47735'), ('name', '2002 FIFA World Cup'), ('c', 'http://www.wikidata.org/entity/Q83459'), ('cname', 'Brazil national football team')]
# [('p', 'http://www.wikidata.org/entity/Q37285'), ('name', '2006 FIFA World Cup'), ('c', 'http://www.wikidata.org/entity/Q676899'), ('cname', 'Italy national association football team')]
# [('p', 'http://www.wikidata.org/entity/Q176883'), ('name', '2010 FIFA World Cup'), ('c', 'http://www.wikidata.org/entity/Q42267'), ('cname', 'Spain national association football team')]
# [('p', 'http://www.wikidata.org/entity/Q79859'), ('name', '2014 FIFA World Cup'), ('c', 'http://www.wikidata.org/entity/Q43310'), ('cname', 'Germany national association football team')]
# [('p', 'http://www.wikidata.org/entity/Q170645'), ('name', '2018 FIFA World Cup'), ('c', 'http://www.wikidata.org/entity/Q47774'), ('cname', 'France national association football team')]
# 21

# %%
#Counting Number of World Cups Won
#[('p', 'http://www.wikidata.org/prop/direct/P1346'), ('name', 'winner')]
queryString = """
SELECT DISTINCT (COUNT(?p) AS ?NumOfWCs) ?c ?cname
WHERE {
   # bind something
   wd:Q19317 wdt:P527 ?p.
   # ?p wdt:P1346 ?c.
   # get the label
   # ?p sc:name ?name.
   # ?c sc:name ?cname.
}
GROUP BY ?c ?cname
HAVING (COUNT(?p) > 1)
LIMIT 200
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('NumOfWCs', '2'), ('c', 'http://www.wikidata.org/entity/Q47774'), ('cname', 'France national association football team')]
# [('NumOfWCs', '5'), ('c', 'http://www.wikidata.org/entity/Q83459'), ('cname', 'Brazil national football team')]
# [('NumOfWCs', '2'), ('c', 'http://www.wikidata.org/entity/Q134916'), ('cname', 'Uruguay national football team')]
# [('NumOfWCs', '2'), ('c', 'http://www.wikidata.org/entity/Q79800'), ('cname', 'Argentina national football team')]
# [('NumOfWCs', '4'), ('c', 'http://www.wikidata.org/entity/Q676899'), ('cname', 'Italy national association football team')]
# [('NumOfWCs', '4'), ('c', 'http://www.wikidata.org/entity/Q43310'), ('cname', 'Germany national association football team')]
# 6

# %%
#Now we have all the countries who won world cups atleast twice 
#So now we will explore their players
#Taking one specific country to find relation between Teams and Players
#('c', 'http://www.wikidata.org/entity/Q676899'), ('cname', 'Italy national association football team')]
queryString = """
SELECT DISTINCT ?p ?name ?aw ?aname
WHERE {
   # bind something
      # ?p ?obj wd:Q676899;
          wdt:P166 ?aw.
   # get the label
   # ?p sc:name ?name.
   # ?aw sc:name ?aname
}
LIMIT 2
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/entity/Q43304'), ('name', 'Marcello Lippi'), ('aw', 'http://www.wikidata.org/entity/Q1847685'), ('aname', 'Italian Football Hall of Fame')]
# [('p', 'http://www.wikidata.org/entity/Q313457'), ('name', 'Enzo Bearzot'), ('aw', 'http://www.wikidata.org/entity/Q1847685'), ('aname', 'Italian Football Hall of Fame')]
# 2

# %%
#Counting Number of World Cups Won
#[('p', 'http://www.wikidata.org/prop/direct/P1346'), ('name', 'winner')]
queryString = """
SELECT DISTINCT (COUNT(?p) AS ?NumOfWCs) ?c ?cname ?jname ?aname
WHERE {
   # bind something
   wd:Q19317 wdt:P527 ?p.
   # ?p wdt:P1346 ?c.
   
   
   # ?j ?obj ?c;
          wdt:P166 ?aw.
   # get the label
   # ?j sc:name ?jname.
   # ?aw sc:name ?aname.
   # get the label
   # ?p sc:name ?name.
   # ?c sc:name ?cname.
}
GROUP BY ?c ?cname ?jname ?aname
HAVING (COUNT(?p) > 1)
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('NumOfWCs', '4'), ('c', 'http://www.wikidata.org/entity/Q676899'), ('cname', 'Italy national association football team'), ('jname', 'Fabio Cannavaro'), ('aname', 'Officer of the Order of Merit of the Italian Republic')]
# [('NumOfWCs', '4'), ('c', 'http://www.wikidata.org/entity/Q676899'), ('cname', 'Italy national association football team'), ('jname', 'Fabio Cannavaro'), ('aname', 'FIFA World Player of the Year')]
# [('NumOfWCs', '4'), ('c', 'http://www.wikidata.org/entity/Q676899'), ('cname', 'Italy national association football team'), ('jname', 'Federico Chiesa'), ('aname', 'Knight of the Order of Merit of the Italian Republic')]
# [('NumOfWCs', '4'), ('c', 'http://www.wikidata.org/entity/Q676899'), ('cname', 'Italy national association football team'), ('jname', 'Ciro Ferrara'), ('aname', 'Knight of the Order of Merit of the Italian Republic')]
# [('NumOfWCs', '4'), ('c', 'http://www.wikidata.org/entity/Q676899'), ('cname', 'Italy national association football team'), ('jname', 'Enzo Bearzot'), ('aname', 'Italian Football Hall of Fame')]
# [('NumOfWCs', '4'), ('c', 'http://www.wikidata.org/entity/Q676899'), ('cname', 'Italy national association football team'), ('jname', 'Gianluigi Buffon'), ('aname', 'Officer of the Order of Merit of the Italian Republic')]
# [('NumOfWCs', '4'), ('c', 'http://www.wikidata.org/entity/Q676899'), ('cname', 'Italy national association football team'), ('jname', 'Giuseppe Giannini'), ('aname', 'Knight of the Order of Merit of the Italian Republic')]
# [('NumOfWCs', '4'), ('c', 'http://www.wikidata.org/entity/Q676899'), ('cname', 'Italy national association football team'), ('jname', 'Francesco Acerbi'), ('aname', 'Knight of the Order of Merit of the Italian Republic')]
# [('NumOfWCs', '4'), ('c', 'http://www.wikidata.org/entity/Q676899'), ('cname', 'Italy national association football team'), ('jname', 'Giorgio Chiellini'), ('aname', 'Knight of the Order of Merit of the Italian Republic')]
# [('NumOfWCs', '4'), ('c', 'http://www.wikidata.org/entity/Q676899'), ('cname', 'Italy national association football team'), ('jname', 'Alessandro Del Piero'), ('aname', 'Officer of the Order of Merit of the Italian Republic')]
# [('NumOfWCs', '4'), ('c', 'http://www.wikidata.org/entity/Q676899'), ('cname', 'Italy national association football team'), ('jname', 'Marco Amelia'), ('aname', 'Knight of the Order of Merit of the Italian Republic')]
# [('NumOfWCs', '4'), ('c', 'http://www.wikidata.org/entity/Q676899'), ('cname', 'Italy national association football team'), ('jname', 'Mauro Bellugi'), ('aname', 'Medal at the athletic prowess')]
# [('NumOfWCs', '4'), ('c', 'http://www.wikidata.org/entity/Q676899'), ('cname', 'Italy national association football team'), ('jname', 'Andrea Barzagli'), ('aname', 'Knight of the Order of Merit of the Italian Republic')]
# [('NumOfWCs', '4'), ('c', 'http://www.wikidata.org/entity/Q676899'), ('cname', 'Italy national association football team'), ('jname', 'Vincenzo Iaquinta'), ('aname', 'Officer of the Order of Merit of the Italian Republic')]
# [('NumOfWCs', '4'), ('c', 'http://www.wikidata.org/entity/Q676899'), ('cname', 'Italy national association football team'), ('jname', 'Roberto Donadoni'), ('aname', 'Knight of the Order of Merit of the Italian Republic')]
# [('NumOfWCs', '4'), ('c', 'http://www.wikidata.org/entity/Q676899'), ('cname', 'Italy national association football team'), ('jname', 'Gaetano Scirea'), ('aname', 'Gold Collar for Sports Merit')]
# [('NumOfWCs', '4'), ('c', 'http://www.wikidata.org/entity/Q676899'), ('cname', 'Italy national association football team'), ('jname', 'Christian Abbiati'), ('aname', 'Knight of the Order of Merit of the Italian Republic')]
# [('NumOfWCs', '2'), ('c', 'http://www.wikidata.org/entity/Q47774'), ('cname', 'France national association football team'), ('jname', 'Eric Cantona'), ('aname', 'English Football Hall of Fame')]
# [('NumOfWCs', '2'), ('c', 'http://www.wikidata.org/entity/Q47774'), ('cname', 'France national association football team'), ('jname', 'Michel Platini'), ('aname', 'Officer of the Legion of Honour')]
# [('NumOfWCs', '2'), ('c', 'http://www.wikidata.org/entity/Q47774'), ('cname', 'France national association football team'), ('jname', 'Pierre Flamion'), ('aname', 'Knight of the National Order of Merit')]
# 20

# %%
#Specifying Award
#[('p', 'http://www.wikidata.org/prop/direct/P1346'), ('name', 'winner')]
queryString = """
SELECT DISTINCT (COUNT(?p) AS ?NumOfWCs) ?c ?cname ?jname ?aname
WHERE {
   # bind something
   wd:Q19317 wdt:P527 ?p.
   # ?p wdt:P1346 ?c.
   
   
   # ?j ?obj ?c;
          wdt:P166 ?aw.
   # get the label
   # ?j sc:name ?jname.
   # ?aw sc:name ?aname.
   # get the label
   # ?p sc:name ?name.
   # ?c sc:name ?cname.
   FILTER(REGEX(?aname,"Ballon d'Or"^^xsd:string))
}
GROUP BY ?c ?cname ?jname ?aname
HAVING (COUNT(?p) > 1)
LIMIT 200
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('NumOfWCs', '2'), ('c', 'http://www.wikidata.org/entity/Q79800'), ('cname', 'Argentina national football team'), ('jname', 'Lionel Messi'), ('aname', "FIFA Ballon d'Or")]
# [('NumOfWCs', '4'), ('c', 'http://www.wikidata.org/entity/Q676899'), ('cname', 'Italy national association football team'), ('jname', 'Paolo Rossi'), ('aname', "Ballon d'Or")]
# [('NumOfWCs', '2'), ('c', 'http://www.wikidata.org/entity/Q47774'), ('cname', 'France national association football team'), ('jname', 'Michel Platini'), ('aname', "Ballon d'Or")]
# [('NumOfWCs', '2'), ('c', 'http://www.wikidata.org/entity/Q47774'), ('cname', 'France national association football team'), ('jname', 'Zinedine Zidane'), ('aname', "Ballon d'Or")]
# [('NumOfWCs', '2'), ('c', 'http://www.wikidata.org/entity/Q47774'), ('cname', 'France national association football team'), ('jname', 'Raymond Kopa'), ('aname', "Ballon d'Or")]
# [('NumOfWCs', '2'), ('c', 'http://www.wikidata.org/entity/Q79800'), ('cname', 'Argentina national football team'), ('jname', 'Lionel Messi'), ('aname', "Ballon d'Or")]
# [('NumOfWCs', '4'), ('c', 'http://www.wikidata.org/entity/Q43310'), ('cname', 'Germany national association football team'), ('jname', 'Lothar Matthäus'), ('aname', "Ballon d'Or")]
# [('NumOfWCs', '4'), ('c', 'http://www.wikidata.org/entity/Q43310'), ('cname', 'Germany national association football team'), ('jname', 'Gerd Müller'), ('aname', "Ballon d'Or")]
# [('NumOfWCs', '4'), ('c', 'http://www.wikidata.org/entity/Q43310'), ('cname', 'Germany national association football team'), ('jname', 'Karl-Heinz Rummenigge'), ('aname', "Ballon d'Or")]
# [('NumOfWCs', '4'), ('c', 'http://www.wikidata.org/entity/Q676899'), ('cname', 'Italy national association football team'), ('jname', 'Omar Sívori'), ('aname', "Ballon d'Or")]
# [('NumOfWCs', '5'), ('c', 'http://www.wikidata.org/entity/Q83459'), ('cname', 'Brazil national football team'), ('jname', 'Rivaldo'), ('aname', "Ballon d'Or")]
# [('NumOfWCs', '2'), ('c', 'http://www.wikidata.org/entity/Q47774'), ('cname', 'France national association football team'), ('jname', 'Jean-Pierre Papin'), ('aname', "Ballon d'Or")]
# [('NumOfWCs', '4'), ('c', 'http://www.wikidata.org/entity/Q676899'), ('cname', 'Italy national association football team'), ('jname', 'Roberto Baggio'), ('aname', "Ballon d'Or")]
# [('NumOfWCs', '5'), ('c', 'http://www.wikidata.org/entity/Q83459'), ('cname', 'Brazil national football team'), ('jname', 'Ronaldo'), ('aname', "Ballon d'Or")]
# [('NumOfWCs', '4'), ('c', 'http://www.wikidata.org/entity/Q43310'), ('cname', 'Germany national association football team'), ('jname', 'Matthias Sammer'), ('aname', "Ballon d'Or")]
# [('NumOfWCs', '2'), ('c', 'http://www.wikidata.org/entity/Q79800'), ('cname', 'Argentina national football team'), ('jname', 'Alfredo Di Stéfano'), ('aname', "Ballon d'Or")]
# [('NumOfWCs', '4'), ('c', 'http://www.wikidata.org/entity/Q676899'), ('cname', 'Italy national association football team'), ('jname', 'Fabio Cannavaro'), ('aname', "Ballon d'Or")]
# [('NumOfWCs', '4'), ('c', 'http://www.wikidata.org/entity/Q676899'), ('cname', 'Italy national association football team'), ('jname', 'Gianni Rivera'), ('aname', "Ballon d'Or")]
# [('NumOfWCs', '5'), ('c', 'http://www.wikidata.org/entity/Q83459'), ('cname', 'Brazil national football team'), ('jname', 'Ronaldinho'), ('aname', "Ballon d'Or")]
# [('NumOfWCs', '2'), ('c', 'http://www.wikidata.org/entity/Q79800'), ('cname', 'Argentina national football team'), ('jname', 'Omar Sívori'), ('aname', "Ballon d'Or")]
# [('NumOfWCs', '5'), ('c', 'http://www.wikidata.org/entity/Q83459'), ('cname', 'Brazil national football team'), ('jname', 'Kaká'), ('aname', "Ballon d'Or")]
# [('NumOfWCs', '4'), ('c', 'http://www.wikidata.org/entity/Q43310'), ('cname', 'Germany national association football team'), ('jname', 'Franz Beckenbauer'), ('aname', "Ballon d'Or")]
# 22

# %% [markdown]
# Final query for this task

# %%
# write your final query
queryString = """
SELECT DISTINCT (COUNT(?p) AS ?NumOfWCs) ?cname ?jname ?aname
WHERE {
   # bind something
   wd:Q19317 wdt:P527 ?p.
   # ?p wdt:P1346 ?c.
   
   
   # ?j ?obj ?c;
          wdt:P166 ?aw.
   # get the label
   # ?j sc:name ?jname.
   # ?aw sc:name ?aname.
   # get the label
   # ?p sc:name ?name.
   # ?c sc:name ?cname.
   FILTER(REGEX(?aname,"Ballon d'Or"^^xsd:string))
}
GROUP BY ?c ?cname ?jname ?aname
HAVING (COUNT(?p) > 1)
LIMIT 200
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('NumOfWCs', '2'), ('cname', 'Argentina national football team'), ('jname', 'Lionel Messi'), ('aname', "FIFA Ballon d'Or")]
# [('NumOfWCs', '4'), ('cname', 'Italy national association football team'), ('jname', 'Paolo Rossi'), ('aname', "Ballon d'Or")]
# [('NumOfWCs', '2'), ('cname', 'France national association football team'), ('jname', 'Michel Platini'), ('aname', "Ballon d'Or")]
# [('NumOfWCs', '2'), ('cname', 'France national association football team'), ('jname', 'Zinedine Zidane'), ('aname', "Ballon d'Or")]
# [('NumOfWCs', '2'), ('cname', 'France national association football team'), ('jname', 'Raymond Kopa'), ('aname', "Ballon d'Or")]
# [('NumOfWCs', '2'), ('cname', 'Argentina national football team'), ('jname', 'Lionel Messi'), ('aname', "Ballon d'Or")]
# [('NumOfWCs', '4'), ('cname', 'Germany national association football team'), ('jname', 'Lothar Matthäus'), ('aname', "Ballon d'Or")]
# [('NumOfWCs', '4'), ('cname', 'Germany national association football team'), ('jname', 'Gerd Müller'), ('aname', "Ballon d'Or")]
# [('NumOfWCs', '4'), ('cname', 'Germany national association football team'), ('jname', 'Karl-Heinz Rummenigge'), ('aname', "Ballon d'Or")]
# [('NumOfWCs', '4'), ('cname', 'Italy national association football team'), ('jname', 'Omar Sívori'), ('aname', "Ballon d'Or")]
# [('NumOfWCs', '5'), ('cname', 'Brazil national football team'), ('jname', 'Rivaldo'), ('aname', "Ballon d'Or")]
# [('NumOfWCs', '2'), ('cname', 'France national association football team'), ('jname', 'Jean-Pierre Papin'), ('aname', "Ballon d'Or")]
# [('NumOfWCs', '4'), ('cname', 'Italy national association football team'), ('jname', 'Roberto Baggio'), ('aname', "Ballon d'Or")]
# [('NumOfWCs', '5'), ('cname', 'Brazil national football team'), ('jname', 'Ronaldo'), ('aname', "Ballon d'Or")]
# [('NumOfWCs', '4'), ('cname', 'Germany national association football team'), ('jname', 'Matthias Sammer'), ('aname', "Ballon d'Or")]
# [('NumOfWCs', '2'), ('cname', 'Argentina national football team'), ('jname', 'Alfredo Di Stéfano'), ('aname', "Ballon d'Or")]
# [('NumOfWCs', '4'), ('cname', 'Italy national association football team'), ('jname', 'Fabio Cannavaro'), ('aname', "Ballon d'Or")]
# [('NumOfWCs', '4'), ('cname', 'Italy national association football team'), ('jname', 'Gianni Rivera'), ('aname', "Ballon d'Or")]
# [('NumOfWCs', '5'), ('cname', 'Brazil national football team'), ('jname', 'Ronaldinho'), ('aname', "Ballon d'Or")]
# [('NumOfWCs', '2'), ('cname', 'Argentina national football team'), ('jname', 'Omar Sívori'), ('aname', "Ballon d'Or")]
# [('NumOfWCs', '5'), ('cname', 'Brazil national football team'), ('jname', 'Kaká'), ('aname', "Ballon d'Or")]
# [('NumOfWCs', '4'), ('cname', 'Germany national association football team'), ('jname', 'Franz Beckenbauer'), ('aname', "Ballon d'Or")]
# 22

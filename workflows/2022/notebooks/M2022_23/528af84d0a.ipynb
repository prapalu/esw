# %% [markdown]
# # General instructions
#
# The goal of the project is to materialize a set of **exploratory workloads** over a real-world, large-scale,  open-domain KG: [WikiData](https://www.wikidata.org/wiki/Wikidata:Main_Page)
#
# An exploratory workload  is composed by a set of queries, where each query is related to the information obtained previously.
#
# An exploratory workload starts with a usually vague, open ended question, and does not assume the person issuing the workload has a clear understanding of the data contained in the target database or its structure.
#
# Remeber that:
#
# 1. All the queries must run in the python notebook
# 2. You can use classes and properties only if you find them via a SPARQL query that must be present in the notebook
# 3. You do not delete useless queries. Keep everything that is synthatically valid
#
# ```
# ?p <http://schema.org/name> ?name .
# ```
#
#     is the BGP returning a human-readable name of a property or a class in Wikidata.

# %%
## SETUP used later

from SPARQLWrapper import SPARQLWrapper, JSON


prefixString = """
##-528af84d0a-##
PREFIX wd: <http://www.wikidata.org/entity/> 
PREFIX wdt: <http://www.wikidata.org/prop/direct/> 
PREFIX sc: <http://schema.org/>
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
"""

# select and construct queries
def run_query(queryString,verbose = True):
    to_run = prefixString + "\n" + queryString

    sparql = SPARQLWrapper("http://a256-gc1-03.srv.aau.dk:5820/sparql")
    sparql.setTimeout(300)
    sparql.setReturnFormat(JSON)
    sparql.setQuery(to_run)

    try :
        results = sparql.query()
        json_results = results.convert()
        if len(json_results['results']['bindings'])==0:
            print("Empty")
            return []
        array = []
        for bindings in json_results['results']['bindings']:
            app =  [ (var, value['value'])  for var, value in bindings.items() ] 
            if verbose:
                print( app)
            array.append(app)
        if verbose:
            print(len(array))
        return array

    except Exception as e :
        print("The operation failed", e)
    
# ASk queries
def run_ask_query(queryString):
    to_run = prefixString + "\n" + queryString

    sparql = SPARQLWrapper("http://a256-gc1-03.srv.aau.dk:5820/sparql")
    sparql.setTimeout(300)
    sparql.setReturnFormat(JSON)
    sparql.setQuery(to_run)

    try :
        return sparql.query().convert()

    except Exception as e :
        print("The operation failed", e)
# Out:
# The history saving thread hit an unexpected error (OperationalError('attempt to write a readonly database')).History will not be written to the database.

# %% [markdown]
# # History Workflow Series ("World Wide Web")
#
# Consider the following exploratory information need:
#
# > Investigate the origins of the World Wide Web and related academic activities and scientists.

# %% [markdown]
# ## Useful URIs for the current workflow
# The following are given:
#
# | IRI           | Description   | Role      |
# | -----------   | -----------   |-----------|
# | `wdt:P1647`   | subproperty   | predicate |
# | `wdt:P31`     | instance of   | predicate |
# | `wdt:P106`    | occupation    | predicate |
# | `wdt:P279`    | subclass      | predicate |
# | `wdt:P27`     | nationality   | predicate |
# | `wdt:P3342`     | Significant person       | predicate |
# | `wd:Q5`| Human       | node |
# | `wd:Q466`| World Wide Web      | node |

# %% [markdown]
# Also consider
#
# ```
# wd:Q466 ?p ?obj .
# ```
#
# is the BGP to retrieve all **properties of World Wide Web**
#
# Please consider that when you return a resource, you should return the IRI and the label of the resource. In particular, when the task require you to identify a BGP the result set must always be a list of couples IRI - label.
#
# The workload should:
#
# 1. Find the inventors of World Wide Web (return IRI and name).
#
# 2. Identify the BGP for hypertext system.
#
# 3. Find all the hypertext systems born before the 1980 (return the IRI and name of the system and the inception date).
#
# 4. Identify the BGP for computer scientist
#
# 5. Find how many computer scientists there are for each continent (consider their citizenship). Return the IRI and name of the continent and the number of scientists for each continent.
#
# 6. Find all the computer scientists who thaught at the University of Cambridge (return IRI and name)
#
# 7. Find all the computer scientists who wrote at least 5 books (please consider only the instances of book, exclude "literary work" or other type of work related to books). Return the IRI and name of the computer scientist and the number of books.

# %% [markdown]
# ## Task 1
# Find the inventors of World Wide Web (return IRI and name).

# %%
# query example
queryString = """
SELECT DISTINCT ?p ?name
WHERE {
   # bind something
   wd:Q466 ?p ?obj .
   # get the label
   # ?p sc:name ?name.
}
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P1051'), ('name', 'PSH ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1225'), ('name', 'U.S. National Archives Identifier')]
# [('p', 'http://www.wikidata.org/prop/direct/P1417'), ('name', 'Encyclopædia Britannica Online ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1430'), ('name', 'OpenPlaques subject ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1482'), ('name', 'Stack Exchange tag')]
# [('p', 'http://www.wikidata.org/prop/direct/P1542'), ('name', 'has effect')]
# [('p', 'http://www.wikidata.org/prop/direct/P1813'), ('name', 'short name')]
# [('p', 'http://www.wikidata.org/prop/direct/P1889'), ('name', 'different from')]
# [('p', 'http://www.wikidata.org/prop/direct/P2004'), ('name', 'NALT ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2163'), ('name', 'FAST ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2184'), ('name', 'history of topic')]
# [('p', 'http://www.wikidata.org/prop/direct/P227'), ('name', 'GND ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2347'), ('name', 'YSO ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P244'), ('name', 'Library of Congress authority ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2581'), ('name', 'BabelNet ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2612'), ('name', 'TED topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P268'), ('name', 'Bibliothèque nationale de France ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('name', 'subclass of')]
# [('p', 'http://www.wikidata.org/prop/direct/P2959'), ('name', 'permanent duplicated item')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('name', 'instance of')]
# 20

# %%
# aim: check more properties for the 'World Wide Web'
# result: the property 'discoverer or inventor' has been found
queryString = """
SELECT DISTINCT ?p ?name
WHERE {
   # bind something
   wd:Q466 ?p ?obj .
   # get the label
   # ?p sc:name ?name.
}
LIMIT 200
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P1051'), ('name', 'PSH ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1225'), ('name', 'U.S. National Archives Identifier')]
# [('p', 'http://www.wikidata.org/prop/direct/P1417'), ('name', 'Encyclopædia Britannica Online ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1430'), ('name', 'OpenPlaques subject ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1482'), ('name', 'Stack Exchange tag')]
# [('p', 'http://www.wikidata.org/prop/direct/P1542'), ('name', 'has effect')]
# [('p', 'http://www.wikidata.org/prop/direct/P1813'), ('name', 'short name')]
# [('p', 'http://www.wikidata.org/prop/direct/P1889'), ('name', 'different from')]
# [('p', 'http://www.wikidata.org/prop/direct/P2004'), ('name', 'NALT ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2163'), ('name', 'FAST ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2184'), ('name', 'history of topic')]
# [('p', 'http://www.wikidata.org/prop/direct/P227'), ('name', 'GND ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2347'), ('name', 'YSO ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P244'), ('name', 'Library of Congress authority ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2581'), ('name', 'BabelNet ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2612'), ('name', 'TED topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P268'), ('name', 'Bibliothèque nationale de France ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('name', 'subclass of')]
# [('p', 'http://www.wikidata.org/prop/direct/P2959'), ('name', 'permanent duplicated item')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('name', 'instance of')]
# [('p', 'http://www.wikidata.org/prop/direct/P3222'), ('name', 'NE.se ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3381'), ('name', 'File Format Wiki page ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3417'), ('name', 'Quora topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3553'), ('name', 'Zhihu topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P373'), ('name', 'Commons category')]
# [('p', 'http://www.wikidata.org/prop/direct/P3827'), ('name', 'JSTOR topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3847'), ('name', 'Open Library subject ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P4342'), ('name', 'Store norske leksikon ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5008'), ('name', 'on focus list of Wikimedia project')]
# [('p', 'http://www.wikidata.org/prop/direct/P5019'), ('name', 'Brockhaus Enzyklopädie online ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P508'), ('name', 'BNCF Thesaurus ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('name', 'has part')]
# [('p', 'http://www.wikidata.org/prop/direct/P5398'), ('name', 'TDKIV term ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P571'), ('name', 'inception')]
# [('p', 'http://www.wikidata.org/prop/direct/P575'), ('name', 'time of discovery or invention')]
# [('p', 'http://www.wikidata.org/prop/direct/P61'), ('name', 'discoverer or inventor')]
# [('p', 'http://www.wikidata.org/prop/direct/P6366'), ('name', 'Microsoft Academic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P646'), ('name', 'Freebase ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6611'), ('name', 'Semantic Scholar topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7033'), ('name', 'Australian Educational Vocabulary ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P737'), ('name', 'influenced by')]
# [('p', 'http://www.wikidata.org/prop/direct/P7818'), ('name', 'French Vikidia ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P793'), ('name', 'significant event')]
# [('p', 'http://www.wikidata.org/prop/direct/P8408'), ('name', 'KBpedia ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P910'), ('name', "topic's main category")]
# [('p', 'http://www.wikidata.org/prop/direct/P935'), ('name', 'Commons gallery')]
# [('p', 'http://www.wikidata.org/prop/direct/P950'), ('name', 'Biblioteca Nacional de España ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2179'), ('name', 'ACM Classification Code (2012)')]
# [('p', 'http://www.wikidata.org/prop/direct/P3893'), ('name', 'public domain date')]
# 49

# %%
# aim: check the property 'discoverer or inventor' of 'World Wide Web' to find the inventors of the W.W.W.
# result: the inventors of the W.W.W. but there is an error in the query: ?p should be sostituted by ?obj
queryString = """
SELECT DISTINCT ?p ?name
WHERE {
   # bind something
   wd:Q466 wdt:P61 ?obj .
   # get the label
   # ?obj sc:name ?name.
}
LIMIT 200
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('name', 'Tim Berners-Lee')]
# [('name', 'Robert Cailliau')]
# 2

# %% [markdown]
# Final query for this task

# %%
# aim: check the property 'discoverer or inventor' of 'World Wide Web' to find the inventors of the W.W.W.
# result: the inventors of the W.W.W.
queryString = """
SELECT DISTINCT ?obj ?name
WHERE {
   # bind something
   wd:Q466 wdt:P61 ?obj .
   # get the label
   # ?obj sc:name ?name.
}
LIMIT 200
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('obj', 'http://www.wikidata.org/entity/Q80'), ('name', 'Tim Berners-Lee')]
# [('obj', 'http://www.wikidata.org/entity/Q92749'), ('name', 'Robert Cailliau')]
# 2

# %% [markdown]
# ## Task 2
# Identify the BGP for hypertext system.

# %%
# aim: check more properties for 'Tim Berners-Lee'
# result: the property 'notable work' has been found (even though Tim Berners-Lee wasn't the first inventor of the hypertext system (MEMEX), he contributed with the http protocol which
#         is surely related to it. Therefore we proceed this way
queryString = """
SELECT DISTINCT ?p ?name
WHERE {
   # bind something
   wd:Q80 ?p ?obj .
   # get the label
   # ?p sc:name ?name.
}
LIMIT 200
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P2930'), ('name', 'INSPIRE-HEP author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6479'), ('name', 'IEEE Xplore author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1006'), ('name', 'Nationale Thesaurus voor Auteurs ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P101'), ('name', 'field of work')]
# [('p', 'http://www.wikidata.org/prop/direct/P1015'), ('name', 'NORAF ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P103'), ('name', 'native language')]
# [('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('p', 'http://www.wikidata.org/prop/direct/P108'), ('name', 'employer')]
# [('p', 'http://www.wikidata.org/prop/direct/P1153'), ('name', 'Scopus author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1207'), ('name', 'NUKAT ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1233'), ('name', 'Internet Speculative Fiction Database author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1263'), ('name', 'NNDB people ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1266'), ('name', 'AlloCiné person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1273'), ('name', 'CANTIC ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1280'), ('name', 'CONOR.SI ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1284'), ('name', 'Munzinger person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1296'), ('name', 'Gran Enciclopèdia Catalana ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1343'), ('name', 'described by source')]
# [('p', 'http://www.wikidata.org/prop/direct/P1344'), ('name', 'participant in')]
# [('p', 'http://www.wikidata.org/prop/direct/P1368'), ('name', 'LNB ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P140'), ('name', 'religion')]
# [('p', 'http://www.wikidata.org/prop/direct/P1412'), ('name', 'languages spoken, written or signed')]
# [('p', 'http://www.wikidata.org/prop/direct/P1417'), ('name', 'Encyclopædia Britannica Online ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1430'), ('name', 'OpenPlaques subject ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1477'), ('name', 'birth name')]
# [('p', 'http://www.wikidata.org/prop/direct/P1556'), ('name', 'zbMATH author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1559'), ('name', 'name in native language')]
# [('p', 'http://www.wikidata.org/prop/direct/P1580'), ('name', 'University of Barcelona authority ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1617'), ('name', 'BBC Things ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P166'), ('name', 'award received')]
# [('p', 'http://www.wikidata.org/prop/direct/P1695'), ('name', 'NLP ID (unique)')]
# [('p', 'http://www.wikidata.org/prop/direct/P172'), ('name', 'ethnic group')]
# [('p', 'http://www.wikidata.org/prop/direct/P18'), ('name', 'image')]
# [('p', 'http://www.wikidata.org/prop/direct/P1816'), ('name', 'National Portrait Gallery (London) person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1890'), ('name', 'CCAB ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P19'), ('name', 'place of birth')]
# [('p', 'http://www.wikidata.org/prop/direct/P2002'), ('name', 'Twitter username')]
# [('p', 'http://www.wikidata.org/prop/direct/P2037'), ('name', 'GitHub username')]
# [('p', 'http://www.wikidata.org/prop/direct/P21'), ('name', 'sex or gender')]
# [('p', 'http://www.wikidata.org/prop/direct/P213'), ('name', 'ISNI')]
# [('p', 'http://www.wikidata.org/prop/direct/P214'), ('name', 'VIAF ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2163'), ('name', 'FAST ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P22'), ('name', 'father')]
# [('p', 'http://www.wikidata.org/prop/direct/P227'), ('name', 'GND ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2435'), ('name', 'PORT person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P244'), ('name', 'Library of Congress authority ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2456'), ('name', 'DBLP author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P25'), ('name', 'mother')]
# [('p', 'http://www.wikidata.org/prop/direct/P2581'), ('name', 'BabelNet ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2600'), ('name', 'Geni.com profile ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2604'), ('name', 'Kinopoisk person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2611'), ('name', 'TED speaker ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P268'), ('name', 'Bibliothèque nationale de France ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P269'), ('name', 'IdRef ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P27'), ('name', 'country of citizenship')]
# [('p', 'http://www.wikidata.org/prop/direct/P271'), ('name', 'CiNii author ID (books)')]
# [('p', 'http://www.wikidata.org/prop/direct/P2734'), ('name', 'Unz Review author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2924'), ('name', 'Great Russian Encyclopedia Online ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2949'), ('name', 'WikiTree person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2963'), ('name', 'Goodreads author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3065'), ('name', 'RERO ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('name', 'instance of')]
# [('p', 'http://www.wikidata.org/prop/direct/P3222'), ('name', 'NE.se ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3373'), ('name', 'sibling')]
# [('p', 'http://www.wikidata.org/prop/direct/P3388'), ('name', 'LittleSis people ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3417'), ('name', 'Quora topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3430'), ('name', 'SNAC ARK ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P345'), ('name', 'IMDb ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P349'), ('name', 'National Diet Library ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3630'), ('name', 'Babelio author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P373'), ('name', 'Commons category')]
# [('p', 'http://www.wikidata.org/prop/direct/P3762'), ('name', 'openMLOL author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3846'), ('name', 'DBC author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3847'), ('name', 'Open Library subject ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3987'), ('name', 'SHARE Catalogue author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P4174'), ('name', 'Wikimedia username')]
# [('p', 'http://www.wikidata.org/prop/direct/P4293'), ('name', 'PM20 folder ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P4342'), ('name', 'Store norske leksikon ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P463'), ('name', 'member of')]
# [('p', 'http://www.wikidata.org/prop/direct/P4666'), ('name', 'CineMagia person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P4789'), ('name', "Who's Who UK ID")]
# [('p', 'http://www.wikidata.org/prop/direct/P4808'), ('name', 'Royal Academy new identifier')]
# [('p', 'http://www.wikidata.org/prop/direct/P4839'), ('name', 'Wolfram Language entity code')]
# [('p', 'http://www.wikidata.org/prop/direct/P496'), ('name', 'ORCID iD')]
# [('p', 'http://www.wikidata.org/prop/direct/P4985'), ('name', 'TMDb person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5008'), ('name', 'on focus list of Wikimedia project')]
# [('p', 'http://www.wikidata.org/prop/direct/P5019'), ('name', 'Brockhaus Enzyklopädie online ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P512'), ('name', 'academic degree')]
# [('p', 'http://www.wikidata.org/prop/direct/P5297'), ('name', 'Companies House officer ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5380'), ('name', 'National Academy of Sciences member ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P551'), ('name', 'residence')]
# [('p', 'http://www.wikidata.org/prop/direct/P5587'), ('name', 'Libris-URI')]
# [('p', 'http://www.wikidata.org/prop/direct/P5617'), ('name', 'Evene ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P569'), ('name', 'date of birth')]
# [('p', 'http://www.wikidata.org/prop/direct/P5739'), ('name', 'Pontificia Università della Santa Croce ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6009'), ('name', 'Techopedia ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6327'), ('name', 'Goodreads character ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P646'), ('name', 'Freebase ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P648'), ('name', 'Open Library ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6706'), ('name', 'De Agostini ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6886'), ('name', 'writing language')]
# [('p', 'http://www.wikidata.org/prop/direct/P69'), ('name', 'educated at')]
# [('p', 'http://www.wikidata.org/prop/direct/P691'), ('name', 'NKCR AUT ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7293'), ('name', 'PLWABN ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P734'), ('name', 'family name')]
# [('p', 'http://www.wikidata.org/prop/direct/P735'), ('name', 'given name')]
# [('p', 'http://www.wikidata.org/prop/direct/P7369'), ('name', 'National Library of Chile ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7859'), ('name', 'WorldCat Identities ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P800'), ('name', 'notable work')]
# [('p', 'http://www.wikidata.org/prop/direct/P8094'), ('name', 'GeneaStar person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8189'), ('name', 'National Library of Israel J9U ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P856'), ('name', 'official website')]
# [('p', 'http://www.wikidata.org/prop/direct/P866'), ('name', 'Perlentaucher ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8687'), ('name', 'social media followers')]
# [('p', 'http://www.wikidata.org/prop/direct/P906'), ('name', 'SELIBR ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P910'), ('name', "topic's main category")]
# [('p', 'http://www.wikidata.org/prop/direct/P9251'), ('name', 'Cyprus University of Technology ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P935'), ('name', 'Commons gallery')]
# [('p', 'http://www.wikidata.org/prop/direct/P937'), ('name', 'work location')]
# [('p', 'http://www.wikidata.org/prop/direct/P950'), ('name', 'Biblioteca Nacional de España ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P9510'), ('name', 'Forbes Russia profile ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P97'), ('name', 'noble title')]
# [('p', 'http://www.wikidata.org/prop/direct/P990'), ('name', "audio recording of the subject's spoken voice")]
# [('p', 'http://www.wikidata.org/prop/direct/P8446'), ('name', 'Gateway to Research person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P864'), ('name', 'ACM Digital Library author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2070'), ('name', 'Fellow of the Royal Society ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2038'), ('name', 'ResearchGate profile ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P4012'), ('name', 'Semantic Scholar author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P9541'), ('name', 'MacArthur Fellows Program ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6640'), ('name', 'JRC Names id')]
# 130

# %%
# aim: check the 'notable work' of 'Tim Berners-Lee'
# result: we found 'HyperText Markup Language' and 'Hypertext Transfer Protocol' that are related to hypertext systems.
queryString = """
SELECT DISTINCT ?obj ?name
WHERE {
   # bind something
   wd:Q80 wdt:P800 ?obj .
   # get the label
   # ?obj sc:name ?name.
}
LIMIT 200
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('obj', 'http://www.wikidata.org/entity/Q466'), ('name', 'World Wide Web')]
# [('obj', 'http://www.wikidata.org/entity/Q8811'), ('name', 'HyperText Markup Language')]
# [('obj', 'http://www.wikidata.org/entity/Q11288'), ('name', 'web server')]
# [('obj', 'http://www.wikidata.org/entity/Q8777'), ('name', 'Hypertext Transfer Protocol')]
# [('obj', 'http://www.wikidata.org/entity/Q590890'), ('name', 'WorldWideWeb')]
# 5

# %%
# aim: check all the properties for  'HyperText Markup Language' and 'Hypertext Transfer Protocol'
# result: we found 'HyperText Markup Language' and 'Hypertext Transfer Protocol' that are related to hypertext systems.
queryString = """
SELECT DISTINCT ?p ?name
WHERE {
   # bind something
   # ?s ?p ?obj .
   # get the label
   # ?p sc:name ?name.
   FILTER (?s IN (wd:Q8811,wd:Q8777))
}
LIMIT 400
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P4742'), ('name', 'Uniform Resource Identifier Scheme')]
# [('p', 'http://www.wikidata.org/prop/direct/P5814'), ('name', 'IANA service name')]
# [('p', 'http://www.wikidata.org/prop/direct/P1014'), ('name', 'Art & Architecture Thesaurus ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1051'), ('name', 'PSH ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1163'), ('name', 'media type')]
# [('p', 'http://www.wikidata.org/prop/direct/P1195'), ('name', 'file extension')]
# [('p', 'http://www.wikidata.org/prop/direct/P1245'), ('name', 'OmegaWiki Defined Meaning')]
# [('p', 'http://www.wikidata.org/prop/direct/P1324'), ('name', 'source code repository')]
# [('p', 'http://www.wikidata.org/prop/direct/P1343'), ('name', 'described by source')]
# [('p', 'http://www.wikidata.org/prop/direct/P1401'), ('name', 'bug tracking system')]
# [('p', 'http://www.wikidata.org/prop/direct/P1417'), ('name', 'Encyclopædia Britannica Online ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1424'), ('name', "topic's main template")]
# [('p', 'http://www.wikidata.org/prop/direct/P144'), ('name', 'based on')]
# [('p', 'http://www.wikidata.org/prop/direct/P1462'), ('name', 'standards body')]
# [('p', 'http://www.wikidata.org/prop/direct/P1482'), ('name', 'Stack Exchange tag')]
# [('p', 'http://www.wikidata.org/prop/direct/P154'), ('name', 'logo image')]
# [('p', 'http://www.wikidata.org/prop/direct/P1557'), ('name', 'manifestation of')]
# [('p', 'http://www.wikidata.org/prop/direct/P1641'), ('name', 'port')]
# [('p', 'http://www.wikidata.org/prop/direct/P17'), ('name', 'country')]
# [('p', 'http://www.wikidata.org/prop/direct/P178'), ('name', 'developer')]
# [('p', 'http://www.wikidata.org/prop/direct/P18'), ('name', 'image')]
# [('p', 'http://www.wikidata.org/prop/direct/P1813'), ('name', 'short name')]
# [('p', 'http://www.wikidata.org/prop/direct/P1889'), ('name', 'different from')]
# [('p', 'http://www.wikidata.org/prop/direct/P2184'), ('name', 'history of topic')]
# [('p', 'http://www.wikidata.org/prop/direct/P227'), ('name', 'GND ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2283'), ('name', 'uses')]
# [('p', 'http://www.wikidata.org/prop/direct/P2347'), ('name', 'YSO ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P244'), ('name', 'Library of Congress authority ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2581'), ('name', 'BabelNet ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P268'), ('name', 'Bibliothèque nationale de France ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P275'), ('name', 'copyright license')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('name', 'subclass of')]
# [('p', 'http://www.wikidata.org/prop/direct/P2910'), ('name', 'icon')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('name', 'instance of')]
# [('p', 'http://www.wikidata.org/prop/direct/P3222'), ('name', 'NE.se ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3381'), ('name', 'File Format Wiki page ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3417'), ('name', 'Quora topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P348'), ('name', 'software version identifier')]
# [('p', 'http://www.wikidata.org/prop/direct/P3553'), ('name', 'Zhihu topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P361'), ('name', 'part of')]
# [('p', 'http://www.wikidata.org/prop/direct/P373'), ('name', 'Commons category')]
# [('p', 'http://www.wikidata.org/prop/direct/P3827'), ('name', 'JSTOR topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3847'), ('name', 'Open Library subject ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3984'), ('name', 'subreddit')]
# [('p', 'http://www.wikidata.org/prop/direct/P4342'), ('name', 'Store norske leksikon ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P4839'), ('name', 'Wolfram Language entity code')]
# [('p', 'http://www.wikidata.org/prop/direct/P5019'), ('name', 'Brockhaus Enzyklopädie online ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P503'), ('name', 'ISO standard')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('name', 'has part')]
# [('p', 'http://www.wikidata.org/prop/direct/P5398'), ('name', 'TDKIV term ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P571'), ('name', 'inception')]
# [('p', 'http://www.wikidata.org/prop/direct/P577'), ('name', 'publication date')]
# [('p', 'http://www.wikidata.org/prop/direct/P5805'), ('name', 'OSI Model layer location')]
# [('p', 'http://www.wikidata.org/prop/direct/P61'), ('name', 'discoverer or inventor')]
# [('p', 'http://www.wikidata.org/prop/direct/P6366'), ('name', 'Microsoft Academic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P646'), ('name', 'Freebase ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6573'), ('name', 'Klexikon article ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6611'), ('name', 'Semantic Scholar topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6857'), ('name', 'JIS standard')]
# [('p', 'http://www.wikidata.org/prop/direct/P747'), ('name', 'has edition or translation')]
# [('p', 'http://www.wikidata.org/prop/direct/P7818'), ('name', 'French Vikidia ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7822'), ('name', 'Italian Vikidia ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8205'), ('name', 'Mozilla Developer Network article')]
# [('p', 'http://www.wikidata.org/prop/direct/P8408'), ('name', 'KBpedia ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P856'), ('name', 'official website')]
# [('p', 'http://www.wikidata.org/prop/direct/P8814'), ('name', 'WordNet 3.1 Synset ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8885'), ('name', 'Namuwiki ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P910'), ('name', "topic's main category")]
# [('p', 'http://www.wikidata.org/prop/direct/P9100'), ('name', 'GitHub topic')]
# [('p', 'http://www.wikidata.org/prop/direct/P92'), ('name', 'main regulatory text')]
# [('p', 'http://www.wikidata.org/prop/direct/P935'), ('name', 'Commons gallery')]
# [('p', 'http://www.wikidata.org/prop/direct/P950'), ('name', 'Biblioteca Nacional de España ID')]
# 72

# %%
# aim: check the 'instance of' property of 'HyperText Markup Language' and 'Hypertext Transfer Protocol'
# result: we found 'markup language'. Maybe we are going far from the objective. Let's give it a try anyway
queryString = """
SELECT DISTINCT ?obj ?name
WHERE {
   # bind something
   # ?s wdt:P31 ?obj .
   # get the label
   # ?obj sc:name ?name.
   FILTER (?s IN (wd:Q8811,wd:Q8777))
}
LIMIT 200
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('obj', 'http://www.wikidata.org/entity/Q15836568'), ('name', 'computer network protocol')]
# [('obj', 'http://www.wikidata.org/entity/Q17537576'), ('name', 'creative work')]
# [('obj', 'http://www.wikidata.org/entity/Q20202982'), ('name', 'Web API')]
# [('obj', 'http://www.wikidata.org/entity/Q235557'), ('name', 'file format')]
# [('obj', 'http://www.wikidata.org/entity/Q2661442'), ('name', 'W3C Recommendation')]
# [('obj', 'http://www.wikidata.org/entity/Q37045'), ('name', 'markup language')]
# 6

# %%
# aim: check the 'markup language' object with its properties
# result: we did not find anything special regarding 'hypertext system'. Maybe we can start again from 'World Wide Web' instead
queryString = """
SELECT DISTINCT ?p ?name ?obj ?objname
WHERE {
   # bind something
   wd:Q37045 ?p ?obj .
   # get the label
   # ?p sc:name ?name .
   # ?obj sc:name ?objname .
}
LIMIT 200
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('name', 'subclass of'), ('obj', 'http://www.wikidata.org/entity/Q494823'), ('objname', 'data format')]
# [('p', 'http://www.wikidata.org/prop/direct/P910'), ('name', "topic's main category"), ('obj', 'http://www.wikidata.org/entity/Q5102677'), ('objname', 'Category:Markup languages')]
# [('p', 'http://www.wikidata.org/prop/direct/P1889'), ('name', 'different from'), ('obj', 'http://www.wikidata.org/entity/Q24451526'), ('objname', 'data serialization format')]
# [('p', 'http://www.wikidata.org/prop/direct/P2670'), ('name', 'has parts of the class'), ('obj', 'http://www.wikidata.org/entity/Q857525'), ('objname', 'annotation')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('name', 'subclass of'), ('obj', 'http://www.wikidata.org/entity/Q17176533'), ('objname', 'software component')]
# [('p', 'http://www.wikidata.org/prop/direct/P2670'), ('name', 'has parts of the class'), ('obj', 'http://www.wikidata.org/entity/Q1260632'), ('objname', 'content')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('name', 'subclass of'), ('obj', 'http://www.wikidata.org/entity/Q629206'), ('objname', 'computer language')]
# 7

# %% [markdown]
# Final query for this task

# %%
# aim: check the 'instance of' and 'subclass' properties of 'World Wide Web'
# result: we found 'hypertext system'
queryString = """
SELECT DISTINCT ?p ?name ?obj ?objname
WHERE {
   # bind something
   wd:Q466 ?p ?obj .
   # get the label
   # ?p sc:name ?name.
   # ?obj sc:name ?objname.
   FILTER(?p IN(wdt:P31,wdt:P279))
}
LIMIT 200
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('name', 'subclass of'), ('obj', 'http://www.wikidata.org/entity/Q1668024'), ('objname', 'service on internet')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('name', 'subclass of'), ('obj', 'http://www.wikidata.org/entity/Q1076968'), ('objname', 'digital media')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('name', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q121182'), ('objname', 'information system')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('name', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q65966993'), ('objname', 'hypertext system')]
# 4

# %% [markdown]
# ## Task 3
# Find all the hypertext systems born before the 1980 (return the IRI and name of the system and the inception date).

# %%
# aim: get all the properties for 'hypertext system'
# result: all the properties for 'hypertext system'
queryString = """
SELECT DISTINCT ?p ?name 
WHERE {
   # bind something
   wd:Q65966993 ?p ?obj .
   # get the label
   # ?p sc:name ?name.
}
LIMIT 200
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('name', 'subclass of')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('name', 'instance of')]
# [('p', 'http://www.wikidata.org/prop/direct/P3847'), ('name', 'Open Library subject ID')]
# 3

# %%
# aim: find all the resources in relation with 'hypertext system' by means of 'instance of'
# result: we found the instances of 'hypertext system'
queryString = """
SELECT DISTINCT ?system ?name
WHERE {
   # bind something
   # ?system wdt:P31 wd:Q65966993 .
   # get the label
   # ?system sc:name ?name.
}
LIMIT 200
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('system', 'http://www.wikidata.org/entity/Q466'), ('name', 'World Wide Web')]
# [('system', 'http://www.wikidata.org/entity/Q370979'), ('name', 'Amigaguide')]
# [('system', 'http://www.wikidata.org/entity/Q2385520'), ('name', 'ENQUIRE')]
# [('system', 'http://www.wikidata.org/entity/Q4994212'), ('name', 'Hypertext Editing System')]
# [('system', 'http://www.wikidata.org/entity/Q5448331'), ('name', 'File Retrieval and Editing System')]
# [('system', 'http://www.wikidata.org/entity/Q785345'), ('name', 'Project Xanadu')]
# [('system', 'http://www.wikidata.org/entity/Q1799609'), ('name', 'HyTime')]
# [('system', 'http://www.wikidata.org/entity/Q7742259'), ('name', 'The Interactive Encyclopedia System')]
# [('system', 'http://www.wikidata.org/entity/Q74587961'), ('name', 'MaxThink')]
# [('system', 'http://www.wikidata.org/entity/Q74590695'), ('name', 'HyperRez')]
# [('system', 'http://www.wikidata.org/entity/Q74667091'), ('name', 'HOUDINI')]
# [('system', 'http://www.wikidata.org/entity/Q66561170'), ('name', 'Visual Knowledge Builder')]
# [('system', 'http://www.wikidata.org/entity/Q66561696'), ('name', 'VIKI')]
# [('system', 'http://www.wikidata.org/entity/Q1166919'), ('name', 'Darwin Information Typing Architecture')]
# [('system', 'http://www.wikidata.org/entity/Q1053749'), ('name', 'HyperCard')]
# [('system', 'http://www.wikidata.org/entity/Q74679064'), ('name', 'TransText')]
# [('system', 'http://www.wikidata.org/entity/Q94638515'), ('name', 'Gemini')]
# [('system', 'http://www.wikidata.org/entity/Q2442968'), ('name', 'ToolBook')]
# [('system', 'http://www.wikidata.org/entity/Q2367048'), ('name', 'SuperCard')]
# [('system', 'http://www.wikidata.org/entity/Q5319181'), ('name', 'Dynatext')]
# [('system', 'http://www.wikidata.org/entity/Q73516071'), ('name', 'Andrew Toolkit')]
# [('system', 'http://www.wikidata.org/entity/Q5964462'), ('name', 'Knowledge Management System')]
# [('system', 'http://www.wikidata.org/entity/Q67170587'), ('name', 'Expeditee')]
# [('system', 'http://www.wikidata.org/entity/Q67147168'), ('name', 'Macweb')]
# [('system', 'http://www.wikidata.org/entity/Q73916721'), ('name', 'HyperWriter!')]
# [('system', 'http://www.wikidata.org/entity/Q15411624'), ('name', 'Twine')]
# [('system', 'http://www.wikidata.org/entity/Q6839396'), ('name', 'Microcosm')]
# [('system', 'http://www.wikidata.org/entity/Q471'), ('name', 'Memex')]
# [('system', 'http://www.wikidata.org/entity/Q2583312'), ('name', 'WinPlus')]
# [('system', 'http://www.wikidata.org/entity/Q73664535'), ('name', 'Folio Views')]
# [('system', 'http://www.wikidata.org/entity/Q66124479'), ('name', 'Hyper-G')]
# [('system', 'http://www.wikidata.org/entity/Q75004603'), ('name', 'IBM LinkWay')]
# [('system', 'http://www.wikidata.org/entity/Q1050365'), ('name', 'oNLine System')]
# [('system', 'http://www.wikidata.org/entity/Q8063246'), ('name', 'ZOG')]
# [('system', 'http://www.wikidata.org/entity/Q66916307'), ('name', 'token_word')]
# [('system', 'http://www.wikidata.org/entity/Q3625272'), ('name', 'Aspen Movie Map')]
# [('system', 'http://www.wikidata.org/entity/Q5358242'), ('name', 'Electronic Document System')]
# [('system', 'http://www.wikidata.org/entity/Q11153199'), ('name', 'Intermedia')]
# [('system', 'http://www.wikidata.org/entity/Q7620478'), ('name', 'Storyspace')]
# [('system', 'http://www.wikidata.org/entity/Q380574'), ('name', 'Knowledge Navigator')]
# [('system', 'http://www.wikidata.org/entity/Q5615425'), ('name', 'Guide')]
# [('system', 'http://www.wikidata.org/entity/Q11793087'), ('name', 'NoteCards')]
# [('system', 'http://www.wikidata.org/entity/Q74428178'), ('name', 'HyperCOSTOC')]
# [('system', 'http://www.wikidata.org/entity/Q66125212'), ('name', 'Konstanz Hypertext System')]
# [('system', 'http://www.wikidata.org/entity/Q74670748'), ('name', 'PC-Hypertext')]
# [('system', 'http://www.wikidata.org/entity/Q63079762'), ('name', 'OpenXanadu')]
# [('system', 'http://www.wikidata.org/entity/Q66821230'), ('name', "Sun's Link Service")]
# [('system', 'http://www.wikidata.org/entity/Q73737542'), ('name', 'HyperPAD')]
# [('system', 'http://www.wikidata.org/entity/Q104714171'), ('name', 'HM-Card')]
# [('system', 'http://www.wikidata.org/entity/Q7060634'), ('name', 'Norton Guides')]
# [('system', 'http://www.wikidata.org/entity/Q7661194'), ('name', 'Symbolics Document Examiner')]
# [('system', 'http://www.wikidata.org/entity/Q74588296'), ('name', 'Hyplus')]
# [('system', 'http://www.wikidata.org/entity/Q67168848'), ('name', 'Udanax Green')]
# 53

# %%
# aim: check the 'inception' property of 'World Wide Web'
# result: the result list is empty. This means that probably it's a literal or data property (hopefully a date).
queryString = """
SELECT DISTINCT ?obj ?name
WHERE {
   # bind something
   wd:Q466 wdt:P571 ?obj .
   # get the label
   # ?obj sc:name ?name.
}
LIMIT 200
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# Empty

# %%
# aim: check the 'inception' property of 'World Wide Web'
# result: we found two possible dates. We assume the first one to be valid in case of multiple dates.
queryString = """
SELECT DISTINCT ?obj
WHERE {
   # bind something
   wd:Q466 wdt:P571 ?obj .
}
LIMIT 200
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('obj', '1989-03-12T00:00:00Z')]
# [('obj', '1990-12-01T00:00:00Z')]
# 2

# %% [markdown]
# Final query for this task

# %%
# aim: find all the 'hypertext system' instances that were born before 1980
# result: all the 'hypertext system' instances that were born before 1980
queryString = """
SELECT DISTINCT ?system ?name ?dateinception
WHERE {
   {
       SELECT ?system ?name (MIN(?datesinception) AS ?dateinception) WHERE{
          # bind something
          # ?system wdt:P31 wd:Q65966993 ;
             # get the label
             sc:name ?name ;
             #get the date
             wdt:P571 ?datesinception .
       }GROUP BY ?system ?name
   }
   
   FILTER (?dateinception < "1980-01-01T00:00:00Z"^^xsd:dateTime)
}
LIMIT 200
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('system', 'http://www.wikidata.org/entity/Q1050365'), ('name', 'oNLine System'), ('dateinception', '1962-01-01T00:00:00Z')]
# [('system', 'http://www.wikidata.org/entity/Q8063246'), ('name', 'ZOG'), ('dateinception', '1977-01-01T00:00:00Z')]
# [('system', 'http://www.wikidata.org/entity/Q4994212'), ('name', 'Hypertext Editing System'), ('dateinception', '1967-01-01T00:00:00Z')]
# [('system', 'http://www.wikidata.org/entity/Q5448331'), ('name', 'File Retrieval and Editing System'), ('dateinception', '1968-01-01T00:00:00Z')]
# [('system', 'http://www.wikidata.org/entity/Q785345'), ('name', 'Project Xanadu'), ('dateinception', '1960-01-01T00:00:00Z')]
# [('system', 'http://www.wikidata.org/entity/Q3625272'), ('name', 'Aspen Movie Map'), ('dateinception', '1978-01-01T00:00:00Z')]
# [('system', 'http://www.wikidata.org/entity/Q5358242'), ('name', 'Electronic Document System'), ('dateinception', '1978-01-01T00:00:00Z')]
# [('system', 'http://www.wikidata.org/entity/Q471'), ('name', 'Memex'), ('dateinception', '1939-01-01T00:00:00Z')]
# 8

# %% [markdown]
# ## Task 4
# Identify the BGP for computer scientist

# %% [markdown]
# Final query for this task

# %%
# aim: check the property 'occupation' for 'Tim Berners-Lee'. He should be considered also as a computer scientist among other possible jobs
# result: the property 'computer scientist' is found
queryString = """
SELECT DISTINCT ?obj ?name
WHERE {
   # bind something
   wd:Q80 wdt:P106 ?obj .
   # get the label
   # ?obj sc:name ?name.
}
LIMIT 200
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('obj', 'http://www.wikidata.org/entity/Q1622272'), ('name', 'university teacher')]
# [('obj', 'http://www.wikidata.org/entity/Q169470'), ('name', 'physicist')]
# [('obj', 'http://www.wikidata.org/entity/Q205375'), ('name', 'inventor')]
# [('obj', 'http://www.wikidata.org/entity/Q81096'), ('name', 'engineer')]
# [('obj', 'http://www.wikidata.org/entity/Q82594'), ('name', 'computer scientist')]
# [('obj', 'http://www.wikidata.org/entity/Q5482740'), ('name', 'programmer')]
# [('obj', 'http://www.wikidata.org/entity/Q6859454'), ('name', 'web developer')]
# 7

# %% [markdown]
# ## Task 5
# Find how many computer scientists there are for each continent (consider their citizenship). Return the IRI and name of the continent and the number of scientists for each continent.

# %%
# aim: get all the properties of 'computer scientist'
# result: the bgp for 'computer scientist'
queryString = """
SELECT DISTINCT ?p ?name
WHERE {
   # bind something
   wd:Q82594 ?p ?obj .
   # get the label
   # ?p sc:name ?name.
}
LIMIT 200
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P1014'), ('name', 'Art & Architecture Thesaurus ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1036'), ('name', 'Dewey Decimal Classification')]
# [('p', 'http://www.wikidata.org/prop/direct/P1245'), ('name', 'OmegaWiki Defined Meaning')]
# [('p', 'http://www.wikidata.org/prop/direct/P1296'), ('name', 'Gran Enciclopèdia Catalana ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P18'), ('name', 'image')]
# [('p', 'http://www.wikidata.org/prop/direct/P1889'), ('name', 'different from')]
# [('p', 'http://www.wikidata.org/prop/direct/P227'), ('name', 'GND ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2283'), ('name', 'uses')]
# [('p', 'http://www.wikidata.org/prop/direct/P2354'), ('name', 'has list')]
# [('p', 'http://www.wikidata.org/prop/direct/P244'), ('name', 'Library of Congress authority ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P268'), ('name', 'Bibliothèque nationale de France ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('name', 'subclass of')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('name', 'instance of')]
# [('p', 'http://www.wikidata.org/prop/direct/P3417'), ('name', 'Quora topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P373'), ('name', 'Commons category')]
# [('p', 'http://www.wikidata.org/prop/direct/P417'), ('name', 'patron saint')]
# [('p', 'http://www.wikidata.org/prop/direct/P425'), ('name', 'field of this occupation')]
# [('p', 'http://www.wikidata.org/prop/direct/P460'), ('name', 'said to be the same as')]
# [('p', 'http://www.wikidata.org/prop/direct/P508'), ('name', 'BNCF Thesaurus ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6186'), ('name', 'category for eponymous categories')]
# [('p', 'http://www.wikidata.org/prop/direct/P646'), ('name', 'Freebase ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7818'), ('name', 'French Vikidia ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8408'), ('name', 'KBpedia ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8814'), ('name', 'WordNet 3.1 Synset ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P910'), ('name', "topic's main category")]
# [('p', 'http://www.wikidata.org/prop/direct/P4652'), ('name', 'ESCO Occupation ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P867'), ('name', 'ROME Occupation Code (v3)')]
# [('p', 'http://www.wikidata.org/prop/direct/P1021'), ('name', 'KldB-2010 occupation code')]
# 28

# %%
# aim: check the property 'country of citizenship' for 'Tim Berners-Lee'. Check a property that might relate it to a continent
# result: the property 'continent' is found
queryString = """
SELECT DISTINCT ?country ?countryname ?p ?pname
WHERE {
   # bind something
    wd:Q80 wdt:P27 ?country .
   
   # get the country label
   # ?country sc:name ?countryname ;
   #get the country properties
            # ?p ?obj .
   # ?p sc:name ?pname .
}
LIMIT 200
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P1036'), ('pname', 'Dewey Decimal Classification')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P1081'), ('pname', 'Human Development Index')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P1082'), ('pname', 'population')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P1125'), ('pname', 'Gini coefficient')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P1151'), ('pname', "topic's main Wikimedia portal")]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P1198'), ('pname', 'unemployment rate')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P122'), ('pname', 'basic form of government')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P1245'), ('pname', 'OmegaWiki Defined Meaning')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P1273'), ('pname', 'CANTIC ID')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P1281'), ('pname', 'WOEID')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P1296'), ('pname', 'Gran Enciclopèdia Catalana ID')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P1304'), ('pname', 'central bank')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P1313'), ('pname', 'office held by head of government')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P1343'), ('pname', 'described by source')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P1344'), ('pname', 'participant in')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P1365'), ('pname', 'replaces')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P1375'), ('pname', 'NSK ID')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P1417'), ('pname', 'Encyclopædia Britannica Online ID')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P1424'), ('pname', "topic's main template")]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P1438'), ('pname', 'Jewish Encyclopedia ID (Russian)')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P1448'), ('pname', 'official name')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P1464'), ('pname', 'category for people born here')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P1465'), ('pname', 'category for people who died here')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P1482'), ('pname', 'Stack Exchange tag')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P150'), ('pname', 'contains administrative territorial entity')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P1549'), ('pname', 'demonym')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P155'), ('pname', 'follows')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P1552'), ('pname', 'has quality')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P1566'), ('pname', 'GeoNames ID')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P158'), ('pname', 'seal image')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P1589'), ('pname', 'lowest point')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P1617'), ('pname', 'BBC Things ID')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P1622'), ('pname', 'driving side')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P163'), ('pname', 'flag')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P1667'), ('pname', 'Getty Thesaurus of Geographic Names ID')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P17'), ('pname', 'country')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P1711'), ('pname', 'British Museum person or institution ID')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P172'), ('pname', 'ethnic group')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P1740'), ('pname', 'category for films shot at this location')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P1791'), ('pname', 'category of people buried here')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P1792'), ('pname', 'category of associated people')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P1813'), ('pname', 'short name')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P1889'), ('pname', 'different from')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P1906'), ('pname', 'office held by head of state')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P194'), ('pname', 'legislative body')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P2004'), ('pname', 'NALT ID')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P2046'), ('pname', 'area')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P208'), ('pname', 'executive body')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P2082'), ('pname', 'M.49 code')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P209'), ('pname', 'highest judicial authority')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P213'), ('pname', 'ISNI')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P214'), ('pname', 'VIAF ID')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P2163'), ('pname', 'FAST ID')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P2184'), ('pname', 'history of topic')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P2250'), ('pname', 'life expectancy')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P2258'), ('pname', 'mobile country code')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P227'), ('pname', 'GND ID')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P2347'), ('pname', 'YSO ID')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P237'), ('pname', 'coat of arms')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P242'), ('pname', 'locator map image')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P244'), ('pname', 'Library of Congress authority ID')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P2468'), ('pname', 'Theatricalia theatre ID')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P2573'), ('pname', 'number of out-of-school children')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P2581'), ('pname', 'BabelNet ID')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P2596'), ('pname', 'culture')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P2633'), ('pname', 'geography of topic')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P268'), ('pname', 'Bibliothèque nationale de France ID')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P269'), ('pname', 'IdRef ID')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P271'), ('pname', 'CiNii author ID (books)')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P2852'), ('pname', 'emergency telephone number')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P2853'), ('pname', 'electrical plug type')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P2855'), ('pname', 'VAT-rate')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P2884'), ('pname', 'mains voltage')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P2924'), ('pname', 'Great Russian Encyclopedia Online ID')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P2936'), ('pname', 'language used')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P2950'), ('pname', 'Nomisma ID')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P2959'), ('pname', 'permanent duplicated item')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P297'), ('pname', 'ISO 3166-1 alpha-2 code')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P2979'), ('pname', 'maritime identification digits')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P298'), ('pname', 'ISO 3166-1 alpha-3 code')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P2981'), ('pname', 'UIC alphabetical country code')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P2982'), ('pname', 'UIC numerical country code')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P2986'), ('pname', 'aircraft registration prefix')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P299'), ('pname', 'ISO 3166-1 numeric code')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P2997'), ('pname', 'age of majority')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P2999'), ('pname', 'age of consent')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P30'), ('pname', 'continent')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P300'), ('pname', 'ISO 3166-2 code')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P3024'), ('pname', 'ITU letter code')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P3067'), ('pname', 'GS1 country code')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P3068'), ('pname', 'WIPO ST.3')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pname', 'instance of')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P3106'), ('pname', 'Guardian topic ID')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P3134'), ('pname', 'TripAdvisor ID')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P3175'), ('pname', 'Statoids ID')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P3222'), ('pname', 'NE.se ID')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P3238'), ('pname', 'trunk prefix')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P3270'), ('pname', 'compulsory education (minimum age)')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P3271'), ('pname', 'compulsory education (maximum age)')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P3348'), ('pname', 'National Library of Greece ID')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P3365'), ('pname', 'Treccani ID')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P3417'), ('pname', 'Quora topic ID')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P3422'), ('pname', 'INSEE countries and foreign territories code')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P3479'), ('pname', 'Omni topic ID')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P349'), ('pname', 'National Diet Library ID')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P35'), ('pname', 'head of state')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P3509'), ('pname', 'Dagens Nyheter topic ID')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P3529'), ('pname', 'median income')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P3553'), ('pname', 'Zhihu topic ID')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P36'), ('pname', 'capital')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P361'), ('pname', 'part of')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P3612'), ('pname', 'Le Monde diplomatique subject ID')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P3616'), ('pname', 'Vision of Britain place ID')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P37'), ('pname', 'official language')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P373'), ('pname', 'Commons category')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P3743'), ('pname', 'ITU/ISO/IEC object identifier')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P3749'), ('pname', 'Google Maps Customer ID')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P38'), ('pname', 'currency')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P3836'), ('pname', 'Pinterest username')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P3896'), ('pname', 'geoshape')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P3911'), ('pname', 'STW Thesaurus for Economics ID')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P3916'), ('pname', 'UNESCO Thesaurus ID')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P395'), ('pname', 'licence plate code')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P3984'), ('pname', 'subreddit')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P402'), ('pname', 'OpenStreetMap relation ID')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P4073'), ('pname', 'Fandom wiki ID')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P409'), ('pname', 'Libraries Australia ID')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P41'), ('pname', 'flag image')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P418'), ('pname', 'seal description')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P421'), ('pname', 'located in time zone')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P4212'), ('pname', 'PACTOLS thesaurus ID')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P4342'), ('pname', 'Store norske leksikon ID')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P4427'), ('pname', 'GACS ID')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P443'), ('pname', 'pronunciation audio')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P4527'), ('pname', 'UK Parliament thesaurus ID')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P4613'), ('pname', 'Encyclopedia of Modern Ukraine ID')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P4619'), ('pname', 'National Library of Brazil ID')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P463'), ('pname', 'member of')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P47'), ('pname', 'shares border with')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P4725'), ('pname', 'C-SPAN organization ID')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P474'), ('pname', 'country calling code')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P4801'), ('pname', 'LoC and MARC vocabularies ID')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P4839'), ('pname', 'Wolfram Language entity code')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P4841'), ('pname', 'total fertility rate')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P486'), ('pname', 'MeSH descriptor ID')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P487'), ('pname', 'Unicode character')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P4973'), ('pname', 'Wikitribune category')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P5002'), ('pname', 'Orthodox Encyclopedia ID')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P5008'), ('pname', 'on focus list of Wikimedia project')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P5063'), ('pname', 'Interlingual Index ID')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P5125'), ('pname', 'Wikimedia outline')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P5180'), ('pname', 'CIVICUS Monitor country entry')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P5198'), ('pname', 'ASC Leiden Thesaurus ID')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P5247'), ('pname', 'Giant Bomb ID')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P5250'), ('pname', 'IAB code')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P530'), ('pname', 'diplomatic relation')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P5337'), ('pname', 'Google News topics ID')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P5400'), ('pname', 'GeoNLP ID')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P5437'), ('pname', 'EuroVoc ID')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P5456'), ('pname', 'TasteAtlas ID')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P5573'), ('pname', 'archINFORM location ID')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P5587'), ('pname', 'Libris-URI')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P5658'), ('pname', 'railway traffic side')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P5698'), ('pname', 'Invasive Species Compendium Datasheet ID')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P571'), ('pname', 'inception')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P6'), ('pname', 'head of government')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P605'), ('pname', 'NUTS code')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P6058'), ('pname', 'Larousse ID')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P610'), ('pname', 'highest point')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P6150'), ('pname', 'Academy Awards Database nominee ID')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P6262'), ('pname', 'Fandom article ID')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P6265'), ('pname', 'MinDat Locality ID')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P6293'), ('pname', 'YSA ID')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P6379'), ('pname', 'has works in the collection')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P6385'), ('pname', 'Krugosvet article')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P6404'), ('pname', "Treccani's Dizionario di Storia ID")]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P6413'), ('pname', 'JORFSearch organization ID')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P646'), ('pname', 'Freebase ID')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P6573'), ('pname', 'Klexikon article ID')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P6706'), ('pname', 'De Agostini ID')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P6713'), ('pname', 'Australian War Memorial ID')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P672'), ('pname', 'MeSH tree code')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P6766'), ('pname', "Who's on First ID")]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P6849'), ('pname', 'DR topic ID')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P6900'), ('pname', 'NicoNicoPedia ID')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P691'), ('pname', 'NKCR AUT ID')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P7012'), ('pname', 'World Encyclopedia of Puppetry Arts ID')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P706'), ('pname', 'located in/on physical feature')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P7157'), ('pname', 'The Top Tens ID')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P7284'), ('pname', 'The Independent topic ID')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P7295'), ('pname', 'Gregorian calendar start date')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P7471'), ('pname', 'iNaturalist place ID')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P7775'), ('pname', 'RationalWiki ID')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P78'), ('pname', 'top-level Internet domain')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P7818'), ('pname', 'French Vikidia ID')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P7822'), ('pname', 'Italian Vikidia ID')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P7827'), ('pname', 'Spanish Vikidia ID')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P7829'), ('pname', 'English Vikidia ID')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P7850'), ('pname', 'Joconde location ID')]
# [('country', 'http://www.wikidata.org/entity/Q145'), ('countryname', 'United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P7859'), ('pname', 'WorldCat Identities ID')]
# 200

# %%
# aim: try getting some persons with their job and continents by filtering their job label with 'computer scientist' (for the reader: the next queries are useless; we already
#      had the 'computer scientist' URI but at the time of writing the queries we completely forgot it... anyway it is used in the last cells of this task to get the job of
#      the considered people)
# result: empty set is found. Maybe the filter is not built correctly
queryString = """
SELECT DISTINCT ?personname ?continent ?continentname
WHERE {
   # bind something
   # ?person wdt:P106 ?job ;
           wdt:P27 ?country ;
           sc:name ?personname .
           
   # getting the continent
   # ?country wdt:P30 ?continent .
   
   # ?continent sc:name ?continentname .
   
   # get the job label
   # ?job sc:name ?jobname .
   FILTER (?jobname = 'computer scientist'^^xsd:string)
}
LIMIT 10
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# Empty

# %%
# aim: try getting some persons with their job and continents without filter to check if the above filter was incorrect
# result: the above filter was incorrect. Maybe double quotes?
queryString = """
SELECT DISTINCT ?personname ?jobname ?continentname
WHERE {
   # bind something
   # ?person wdt:P106 ?job ;
           wdt:P27 ?country ;
           sc:name ?personname .
           
   # getting the continent
   # ?country wdt:P30 ?continent .
   # getting the continent label
   # ?continent sc:name ?continentname .
   
   # get the job label
   # ?job sc:name ?jobname .
   #FILTER (?jobname = 'computer scientist')
}
LIMIT 10
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('personname', 'Zhao Weigu'), ('jobname', 'military commander'), ('continentname', 'Asia')]
# [('personname', 'Wei Xianxin'), ('jobname', 'politician'), ('continentname', 'Asia')]
# [('personname', 'Qooqai tayu'), ('jobname', 'tribal chief'), ('continentname', 'Asia')]
# [('personname', 'Zhao Shoudu'), ('jobname', 'military commander'), ('continentname', 'Asia')]
# [('personname', 'Zhao Weiji'), ('jobname', 'military commander'), ('continentname', 'Asia')]
# [('personname', 'Zhao Defang'), ('jobname', 'military personnel'), ('continentname', 'Asia')]
# [('personname', 'Emperor Taizu of Song'), ('jobname', 'ruler'), ('continentname', 'Asia')]
# [('personname', 'Emperor Taizu of Song'), ('jobname', 'military commander'), ('continentname', 'Asia')]
# [('personname', 'Zhao Dezhao'), ('jobname', 'military personnel'), ('continentname', 'Asia')]
# [('personname', 'Qian Chen'), ('jobname', 'politician'), ('continentname', 'Asia')]
# 10

# %%
# aim: try getting some persons with their job and continents by filtering their job label with 'computer scientist'
# result: empty set is found. The filter is still not built correctly... Maybe without xsd:string ?
queryString = """
SELECT DISTINCT ?personname ?jobname ?continentname
WHERE {
   # bind something
   # ?person wdt:P106 ?job ;
           wdt:P27 ?country ;
           sc:name ?personname .
           
   # getting the continent
   # ?country wdt:P30 ?continent .
   # getting the continent label
   # ?continent sc:name ?continentname .
   
   # get the job label
   # ?job sc:name ?jobname .
   FILTER (?jobname = "computer scientist"^^xsd:string)
}
LIMIT 10
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# Empty

# %%
# aim: try getting some persons with their job and continents by filtering their job label with 'computer scientist'
# result: empty set is found. The filter is still not built correctly. Let's go with a regex
queryString = """
SELECT DISTINCT ?personname ?jobname ?continentname
WHERE {
   # bind something
   # ?person wdt:P106 ?job ;
           wdt:P27 ?country ;
           sc:name ?personname .
           
   # getting the continent
   # ?country wdt:P30 ?continent .
   # getting the continent label
   # ?continent sc:name ?continentname .
   
   # get the job label
   # ?job sc:name ?jobname .
   FILTER (?jobname = "computer scientist")
}
LIMIT 10
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# Empty

# %%
# aim: try getting some persons with their job and continents by filtering their job label with 'computer scientist' through a regex
# result: the regex is fine but it's slow. We try with exact regex matching
queryString = """
SELECT DISTINCT ?personname ?jobname ?continentname
WHERE {
   # bind something
   # ?person wdt:P106 ?job ;
           wdt:P27 ?country ;
           sc:name ?personname .
           
   # getting the continent
   # ?country wdt:P30 ?continent .
   # getting the continent label
   # ?continent sc:name ?continentname .
   
   # get the job label
   # ?job sc:name ?jobname .
   FILTER regex(?jobname, "computer scientist", "i")
}
LIMIT 10
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('personname', 'Seinosuke Toda'), ('jobname', 'computer scientist'), ('continentname', 'Asia')]
# [('personname', 'Kevin Poulsen'), ('jobname', 'computer scientist'), ('continentname', 'North America')]
# [('personname', 'Kevin Poulsen'), ('jobname', 'computer scientist'), ('continentname', 'Insular Oceania')]
# [('personname', 'Michael Barr'), ('jobname', 'computer scientist'), ('continentname', 'North America')]
# [('personname', 'Valeria de Paiva'), ('jobname', 'computer scientist'), ('continentname', 'South America')]
# [('personname', 'Valeria de Paiva'), ('jobname', 'computer scientist'), ('continentname', 'Europe')]
# [('personname', 'Ernesto Damiani'), ('jobname', 'computer scientist'), ('continentname', 'Europe')]
# [('personname', 'Liang-Jie Zhang'), ('jobname', 'computer scientist'), ('continentname', 'North America')]
# [('personname', 'Liang-Jie Zhang'), ('jobname', 'computer scientist'), ('continentname', 'Insular Oceania')]
# [('personname', 'Jeffrey Shallit'), ('jobname', 'computer scientist'), ('continentname', 'North America')]
# 10

# %%
# aim: try getting some persons with their job and continents by filtering their job label with 'computer scientist' through an exact matching regex
# result: the regex is not working. It's better to use the 'computer scientist's URI for filtering.

queryString = """
SELECT DISTINCT ?personname ?jobname ?continentname
WHERE {
   # bind something
   # ?person wdt:P106 ?job ;
           wdt:P27 ?country ;
           sc:name ?personname .
           
   # getting the continent
   # ?country wdt:P30 ?continent .
   # getting the continent label
   # ?continent sc:name ?continentname .
   
   # get the job label
   # ?job sc:name ?jobname .
   FILTER regex(?jobname, "^computer scientist$")
}
LIMIT 10
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# Empty

# %%
# aim: try getting some persons with their job and continents by filtering their job label with 'computer scientist' through a regex obtaining the 
#      'computer scientist's URI
# result: we got the 'computer scientist's URI. We already had it so all the above steps could have been avoided!
queryString = """
SELECT DISTINCT ?personname ?job ?jobname ?continentname
WHERE {
   # bind something
   # ?person wdt:P106 ?job ;
           wdt:P27 ?country ;
           sc:name ?personname .
           
   # getting the continent
   # ?country wdt:P30 ?continent .
   # getting the continent label
   # ?continent sc:name ?continentname .
   
   # get the job label
   # ?job sc:name ?jobname .
   FILTER regex(?jobname, "computer scientist")
}
LIMIT 10
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('personname', 'Seinosuke Toda'), ('job', 'http://www.wikidata.org/entity/Q82594'), ('jobname', 'computer scientist'), ('continentname', 'Asia')]
# [('personname', 'Kevin Poulsen'), ('job', 'http://www.wikidata.org/entity/Q82594'), ('jobname', 'computer scientist'), ('continentname', 'North America')]
# [('personname', 'Kevin Poulsen'), ('job', 'http://www.wikidata.org/entity/Q82594'), ('jobname', 'computer scientist'), ('continentname', 'Insular Oceania')]
# [('personname', 'Michael Barr'), ('job', 'http://www.wikidata.org/entity/Q82594'), ('jobname', 'computer scientist'), ('continentname', 'North America')]
# [('personname', 'Valeria de Paiva'), ('job', 'http://www.wikidata.org/entity/Q82594'), ('jobname', 'computer scientist'), ('continentname', 'South America')]
# [('personname', 'Valeria de Paiva'), ('job', 'http://www.wikidata.org/entity/Q82594'), ('jobname', 'computer scientist'), ('continentname', 'Europe')]
# [('personname', 'Ernesto Damiani'), ('job', 'http://www.wikidata.org/entity/Q82594'), ('jobname', 'computer scientist'), ('continentname', 'Europe')]
# [('personname', 'Liang-Jie Zhang'), ('job', 'http://www.wikidata.org/entity/Q82594'), ('jobname', 'computer scientist'), ('continentname', 'North America')]
# [('personname', 'Liang-Jie Zhang'), ('job', 'http://www.wikidata.org/entity/Q82594'), ('jobname', 'computer scientist'), ('continentname', 'Insular Oceania')]
# [('personname', 'Jeffrey Shallit'), ('job', 'http://www.wikidata.org/entity/Q82594'), ('jobname', 'computer scientist'), ('continentname', 'North America')]
# 10

# %%
# aim: get some persons with their job and continent to check that everything is fine before grouping
# result: the result set seems to be ok
queryString = """
SELECT DISTINCT ?personname ?jobname ?continentname
WHERE {
   # bind something
   # ?person wdt:P106 ?job ;
           wdt:P27 ?country ;
           sc:name ?personname .
           
   # getting the continent
   # ?country wdt:P30 ?continent .
   # getting the continent label
   # ?continent sc:name ?continentname .
   
   # get the job label
   # ?job sc:name ?jobname .
   FILTER (?job = wd:Q82594)
}
LIMIT 50
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('personname', 'David Naccache'), ('jobname', 'computer scientist'), ('continentname', 'Africa')]
# [('personname', 'Carsten Haitzler'), ('jobname', 'computer scientist'), ('continentname', 'Africa')]
# [('personname', 'Clarisse Iribagiza'), ('jobname', 'computer scientist'), ('continentname', 'Africa')]
# [('personname', 'Seymour Papert'), ('jobname', 'computer scientist'), ('continentname', 'Africa')]
# [('personname', 'Wanda Orlikowski'), ('jobname', 'computer scientist'), ('continentname', 'Africa')]
# [('personname', 'Theo de Raadt'), ('jobname', 'computer scientist'), ('continentname', 'Africa')]
# [('personname', 'Lior Pachter'), ('jobname', 'computer scientist'), ('continentname', 'Africa')]
# [('personname', 'Valeria de Paiva'), ('jobname', 'computer scientist'), ('continentname', 'South America')]
# [('personname', 'Renato M. E. Sabbatini'), ('jobname', 'computer scientist'), ('continentname', 'South America')]
# [('personname', 'Jean Paul Jacob'), ('jobname', 'computer scientist'), ('continentname', 'South America')]
# [('personname', 'Ronnie Alves'), ('jobname', 'computer scientist'), ('continentname', 'South America')]
# [('personname', 'Gisele Lobo Pappa'), ('jobname', 'computer scientist'), ('continentname', 'South America')]
# [('personname', 'Roberto Ierusalimschy'), ('jobname', 'computer scientist'), ('continentname', 'South America')]
# [('personname', 'Ricardo Baeza-Yates'), ('jobname', 'computer scientist'), ('continentname', 'South America')]
# [('personname', 'Lum Zhaveli'), ('jobname', 'computer scientist'), ('continentname', 'Europe')]
# [('personname', 'Svetlana Selezneva'), ('jobname', 'computer scientist'), ('continentname', 'Europe')]
# [('personname', 'Kurt Gödel'), ('jobname', 'computer scientist'), ('continentname', 'Europe')]
# [('personname', 'Michel Robert'), ('jobname', 'computer scientist'), ('continentname', 'Europe')]
# [('personname', 'Bertrand Meyer'), ('jobname', 'computer scientist'), ('continentname', 'Europe')]
# [('personname', 'Francis Bach'), ('jobname', 'computer scientist'), ('continentname', 'Europe')]
# [('personname', 'Anne Siegel'), ('jobname', 'computer scientist'), ('continentname', 'Europe')]
# [('personname', 'Benoît Minisini'), ('jobname', 'computer scientist'), ('continentname', 'Europe')]
# [('personname', 'Philippe Dreyfus'), ('jobname', 'computer scientist'), ('continentname', 'Europe')]
# [('personname', 'Nathalie Lauraine-Boulyguina'), ('jobname', 'computer scientist'), ('continentname', 'Europe')]
# [('personname', 'Jacques Vallée'), ('jobname', 'computer scientist'), ('continentname', 'Europe')]
# [('personname', 'Henri Gouraud'), ('jobname', 'computer scientist'), ('continentname', 'Europe')]
# [('personname', 'Jean-Paul Delahaye'), ('jobname', 'computer scientist'), ('continentname', 'Europe')]
# [('personname', 'François Bourdoncle'), ('jobname', 'computer scientist'), ('continentname', 'Europe')]
# [('personname', 'Henri Crohas'), ('jobname', 'computer scientist'), ('continentname', 'Europe')]
# [('personname', 'René de Possel'), ('jobname', 'computer scientist'), ('continentname', 'Europe')]
# [('personname', 'Fabrice Bellard'), ('jobname', 'computer scientist'), ('continentname', 'Europe')]
# [('personname', 'Jean-François Pillou'), ('jobname', 'computer scientist'), ('continentname', 'Europe')]
# [('personname', 'Bruno Oudet'), ('jobname', 'computer scientist'), ('continentname', 'Europe')]
# [('personname', 'Jacques Stern'), ('jobname', 'computer scientist'), ('continentname', 'Europe')]
# [('personname', 'Marcel-Paul Schützenberger'), ('jobname', 'computer scientist'), ('continentname', 'Europe')]
# [('personname', 'Jean-Loup Gailly'), ('jobname', 'computer scientist'), ('continentname', 'Europe')]
# [('personname', 'Bernard Chazelle'), ('jobname', 'computer scientist'), ('continentname', 'Europe')]
# [('personname', 'Michel Raynal'), ('jobname', 'computer scientist'), ('continentname', 'Europe')]
# [('personname', 'Michel Monpetit'), ('jobname', 'computer scientist'), ('continentname', 'Europe')]
# [('personname', 'Ludovic Pommeret'), ('jobname', 'computer scientist'), ('continentname', 'Europe')]
# [('personname', 'Colette Rolland'), ('jobname', 'computer scientist'), ('continentname', 'Europe')]
# [('personname', 'Monique Laurent'), ('jobname', 'computer scientist'), ('continentname', 'Europe')]
# [('personname', 'Pierre-Yves Oudeyer'), ('jobname', 'computer scientist'), ('continentname', 'Europe')]
# [('personname', 'Yann LeCun'), ('jobname', 'computer scientist'), ('continentname', 'Europe')]
# [('personname', 'Marie Doumic'), ('jobname', 'computer scientist'), ('continentname', 'Europe')]
# [('personname', 'Christian Huitema'), ('jobname', 'computer scientist'), ('continentname', 'Europe')]
# [('personname', 'Dan Serfaty'), ('jobname', 'computer scientist'), ('continentname', 'Europe')]
# [('personname', 'François Chenique'), ('jobname', 'computer scientist'), ('continentname', 'Europe')]
# [('personname', 'Joël de Rosnay'), ('jobname', 'computer scientist'), ('continentname', 'Europe')]
# [('personname', 'Catherine Dufour'), ('jobname', 'computer scientist'), ('continentname', 'Europe')]
# 50

# %% [markdown]
# Final query for this task

# %%
# aim: get the amount of persons who have worked as 'computer scientist' for each continent 
# result: the amount of persons who have worked as 'computer scientist' for each continent 
queryString = """
SELECT DISTINCT ?continent ?continentname (COUNT(*) AS ?numberofscientists) 
WHERE {
   # bind something
   # ?person wdt:P106 ?job ;
           wdt:P27 ?country ;
           sc:name ?personname .
           
   # getting the continent
   # ?country wdt:P30 ?continent .
   # getting the continent label
   # ?continent sc:name ?continentname .
   
   # get the job label
   # ?job sc:name ?jobname .
   FILTER (?job = wd:Q82594)
} GROUP BY ?continent ?continentname
LIMIT 50
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('continent', 'http://www.wikidata.org/entity/Q18'), ('continentname', 'South America'), ('numberofscientists', '92')]
# [('continent', 'http://www.wikidata.org/entity/Q538'), ('continentname', 'Insular Oceania'), ('numberofscientists', '2479')]
# [('continent', 'http://www.wikidata.org/entity/Q49'), ('continentname', 'North America'), ('numberofscientists', '2782')]
# [('continent', 'http://www.wikidata.org/entity/Q46'), ('continentname', 'Europe'), ('numberofscientists', '3443')]
# [('continent', 'http://www.wikidata.org/entity/Q5401'), ('continentname', 'Eurasia'), ('numberofscientists', '23')]
# [('continent', 'http://www.wikidata.org/entity/Q48'), ('continentname', 'Asia'), ('numberofscientists', '908')]
# [('continent', 'http://www.wikidata.org/entity/Q15'), ('continentname', 'Africa'), ('numberofscientists', '76')]
# 7

# %% [markdown]
# ## Task 6
# Find all the computer scientists who thaught at the University of Cambridge (return IRI and name)

# %%
# aim: get all the properties of 'university teacher'
# result: nothing really special is found. Maybe with the property 'work location' since we discovered that Berner's Lee is or was a 'university teacher'
queryString = """
SELECT DISTINCT ?p ?name
WHERE {
   # bind something
   wd:Q1622272 ?p ?obj .
   # get the label
   # ?p sc:name ?name.
}
LIMIT 200
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P1036'), ('name', 'Dewey Decimal Classification')]
# [('p', 'http://www.wikidata.org/prop/direct/P1889'), ('name', 'different from')]
# [('p', 'http://www.wikidata.org/prop/direct/P227'), ('name', 'GND ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P244'), ('name', 'Library of Congress authority ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2671'), ('name', 'Google Knowledge Graph ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P268'), ('name', 'Bibliothèque nationale de France ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('name', 'subclass of')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('name', 'instance of')]
# [('p', 'http://www.wikidata.org/prop/direct/P3417'), ('name', 'Quora topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3911'), ('name', 'STW Thesaurus for Economics ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P425'), ('name', 'field of this occupation')]
# [('p', 'http://www.wikidata.org/prop/direct/P460'), ('name', 'said to be the same as')]
# [('p', 'http://www.wikidata.org/prop/direct/P487'), ('name', 'Unicode character')]
# [('p', 'http://www.wikidata.org/prop/direct/P8365'), ('name', 'Thesaurus Sozialwissenschaften ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P910'), ('name', "topic's main category")]
# [('p', 'http://www.wikidata.org/prop/direct/P920'), ('name', 'LEM ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P950'), ('name', 'Biblioteca Nacional de España ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P952'), ('name', 'ISCO-88 occupation code')]
# 18

# %%
# aim: get all the objects related to 'work location' of 'Berner's Lee'
# result: we just found that he worked at CERN: no relations with Universities. Maybe instead of checking his profession as a teacher, we should check potential
#         relations with his student career
queryString = """
SELECT DISTINCT ?obj ?name
WHERE {
   # bind something
   wd:Q80 wdt:P937 ?obj .
   # get the label
   # ?obj sc:name ?name.
}
LIMIT 200
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('obj', 'http://www.wikidata.org/entity/Q42944'), ('name', 'CERN')]
# 1

# %%
# aim: get all the objects related to 'educated at' and 'academic degree' to find possible universities
# result: found some objects that might be related to universities
queryString = """
SELECT DISTINCT ?education ?educationname ?obj ?name
WHERE {
   # bind something
   wd:Q80 ?education ?obj .
   # get the label
   # ?obj sc:name ?name .
   # ?education sc:name ?educationname.
   FILTER (?education IN (wdt:P512,wdt:P69))
}
LIMIT 200
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('education', 'http://www.wikidata.org/prop/direct/P69'), ('educationname', 'educated at'), ('obj', 'http://www.wikidata.org/entity/Q73094'), ('name', "The Queen's College")]
# [('education', 'http://www.wikidata.org/prop/direct/P69'), ('educationname', 'educated at'), ('obj', 'http://www.wikidata.org/entity/Q5369138'), ('name', 'Emanuel School')]
# [('education', 'http://www.wikidata.org/prop/direct/P512'), ('educationname', 'academic degree'), ('obj', 'http://www.wikidata.org/entity/Q121594'), ('name', 'professor')]
# [('education', 'http://www.wikidata.org/prop/direct/P512'), ('educationname', 'academic degree'), ('obj', 'http://www.wikidata.org/entity/Q1765120'), ('name', 'Bachelor of Arts')]
# 4

# %%
# aim: get all the objects and paths related to 'educated at' and 'academic degree' to find possible universities
# result: there are many results. We decide to check something about 'Bachelor of Arts'
queryString = """
SELECT DISTINCT ?educationname ?obj ?name ?p2 ?namep2
WHERE {
   # bind something
   wd:Q80 ?education ?obj .
   # ?obj ?p2 ?obj2 .
   # ?p2 sc:name ?namep2 .
   #?obj2 sc:name ?nameobj2 .
   # get the label
   # ?obj sc:name ?name .
   # ?education sc:name ?educationname.
   FILTER (?education IN (wdt:P512,wdt:P69))
}
LIMIT 200
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('educationname', 'academic degree'), ('obj', 'http://www.wikidata.org/entity/Q121594'), ('name', 'professor'), ('p2', 'http://www.wikidata.org/prop/direct/P3729'), ('namep2', 'next lower rank')]
# [('educationname', 'educated at'), ('obj', 'http://www.wikidata.org/entity/Q73094'), ('name', "The Queen's College"), ('p2', 'http://www.wikidata.org/prop/direct/P3057'), ('namep2', 'Charity Commission no.')]
# [('educationname', 'educated at'), ('obj', 'http://www.wikidata.org/entity/Q73094'), ('name', "The Queen's College"), ('p2', 'http://www.wikidata.org/prop/direct/P1004'), ('namep2', 'MusicBrainz place ID')]
# [('educationname', 'academic degree'), ('obj', 'http://www.wikidata.org/entity/Q121594'), ('name', 'professor'), ('p2', 'http://www.wikidata.org/prop/direct/P1014'), ('namep2', 'Art & Architecture Thesaurus ID')]
# [('educationname', 'educated at'), ('obj', 'http://www.wikidata.org/entity/Q73094'), ('name', "The Queen's College"), ('p2', 'http://www.wikidata.org/prop/direct/P112'), ('namep2', 'founded by')]
# [('educationname', 'educated at'), ('obj', 'http://www.wikidata.org/entity/Q5369138'), ('name', 'Emanuel School'), ('p2', 'http://www.wikidata.org/prop/direct/P112'), ('namep2', 'founded by')]
# [('educationname', 'academic degree'), ('obj', 'http://www.wikidata.org/entity/Q121594'), ('name', 'professor'), ('p2', 'http://www.wikidata.org/prop/direct/P1245'), ('namep2', 'OmegaWiki Defined Meaning')]
# [('educationname', 'academic degree'), ('obj', 'http://www.wikidata.org/entity/Q1765120'), ('name', 'Bachelor of Arts'), ('p2', 'http://www.wikidata.org/prop/direct/P1245'), ('namep2', 'OmegaWiki Defined Meaning')]
# [('educationname', 'educated at'), ('obj', 'http://www.wikidata.org/entity/Q73094'), ('name', "The Queen's College"), ('p2', 'http://www.wikidata.org/prop/direct/P131'), ('namep2', 'located in the administrative territorial entity')]
# [('educationname', 'educated at'), ('obj', 'http://www.wikidata.org/entity/Q5369138'), ('name', 'Emanuel School'), ('p2', 'http://www.wikidata.org/prop/direct/P131'), ('namep2', 'located in the administrative territorial entity')]
# [('educationname', 'educated at'), ('obj', 'http://www.wikidata.org/entity/Q5369138'), ('name', 'Emanuel School'), ('p2', 'http://www.wikidata.org/prop/direct/P1329'), ('namep2', 'phone number')]
# [('educationname', 'academic degree'), ('obj', 'http://www.wikidata.org/entity/Q121594'), ('name', 'professor'), ('p2', 'http://www.wikidata.org/prop/direct/P1343'), ('namep2', 'described by source')]
# [('educationname', 'educated at'), ('obj', 'http://www.wikidata.org/entity/Q73094'), ('name', "The Queen's College"), ('p2', 'http://www.wikidata.org/prop/direct/P138'), ('namep2', 'named after')]
# [('educationname', 'educated at'), ('obj', 'http://www.wikidata.org/entity/Q5369138'), ('name', 'Emanuel School'), ('p2', 'http://www.wikidata.org/prop/direct/P140'), ('namep2', 'religion')]
# [('educationname', 'academic degree'), ('obj', 'http://www.wikidata.org/entity/Q1765120'), ('name', 'Bachelor of Arts'), ('p2', 'http://www.wikidata.org/prop/direct/P1417'), ('namep2', 'Encyclopædia Britannica Online ID')]
# [('educationname', 'educated at'), ('obj', 'http://www.wikidata.org/entity/Q73094'), ('name', "The Queen's College"), ('p2', 'http://www.wikidata.org/prop/direct/P1448'), ('namep2', 'official name')]
# [('educationname', 'educated at'), ('obj', 'http://www.wikidata.org/entity/Q73094'), ('name', "The Queen's College"), ('p2', 'http://www.wikidata.org/prop/direct/P154'), ('namep2', 'logo image')]
# [('educationname', 'educated at'), ('obj', 'http://www.wikidata.org/entity/Q73094'), ('name', "The Queen's College"), ('p2', 'http://www.wikidata.org/prop/direct/P17'), ('namep2', 'country')]
# [('educationname', 'educated at'), ('obj', 'http://www.wikidata.org/entity/Q5369138'), ('name', 'Emanuel School'), ('p2', 'http://www.wikidata.org/prop/direct/P17'), ('namep2', 'country')]
# [('educationname', 'academic degree'), ('obj', 'http://www.wikidata.org/entity/Q121594'), ('name', 'professor'), ('p2', 'http://www.wikidata.org/prop/direct/P1709'), ('namep2', 'equivalent class')]
# [('educationname', 'academic degree'), ('obj', 'http://www.wikidata.org/entity/Q121594'), ('name', 'professor'), ('p2', 'http://www.wikidata.org/prop/direct/P18'), ('namep2', 'image')]
# [('educationname', 'educated at'), ('obj', 'http://www.wikidata.org/entity/Q73094'), ('name', "The Queen's College"), ('p2', 'http://www.wikidata.org/prop/direct/P18'), ('namep2', 'image')]
# [('educationname', 'academic degree'), ('obj', 'http://www.wikidata.org/entity/Q121594'), ('name', 'professor'), ('p2', 'http://www.wikidata.org/prop/direct/P1813'), ('namep2', 'short name')]
# [('educationname', 'academic degree'), ('obj', 'http://www.wikidata.org/entity/Q1765120'), ('name', 'Bachelor of Arts'), ('p2', 'http://www.wikidata.org/prop/direct/P1813'), ('namep2', 'short name')]
# [('educationname', 'academic degree'), ('obj', 'http://www.wikidata.org/entity/Q121594'), ('name', 'professor'), ('p2', 'http://www.wikidata.org/prop/direct/P1889'), ('namep2', 'different from')]
# [('educationname', 'academic degree'), ('obj', 'http://www.wikidata.org/entity/Q1765120'), ('name', 'Bachelor of Arts'), ('p2', 'http://www.wikidata.org/prop/direct/P1889'), ('namep2', 'different from')]
# [('educationname', 'educated at'), ('obj', 'http://www.wikidata.org/entity/Q73094'), ('name', "The Queen's College"), ('p2', 'http://www.wikidata.org/prop/direct/P213'), ('namep2', 'ISNI')]
# [('educationname', 'educated at'), ('obj', 'http://www.wikidata.org/entity/Q5369138'), ('name', 'Emanuel School'), ('p2', 'http://www.wikidata.org/prop/direct/P213'), ('namep2', 'ISNI')]
# [('educationname', 'educated at'), ('obj', 'http://www.wikidata.org/entity/Q73094'), ('name', "The Queen's College"), ('p2', 'http://www.wikidata.org/prop/direct/P214'), ('namep2', 'VIAF ID')]
# [('educationname', 'educated at'), ('obj', 'http://www.wikidata.org/entity/Q73094'), ('name', "The Queen's College"), ('p2', 'http://www.wikidata.org/prop/direct/P227'), ('namep2', 'GND ID')]
# [('educationname', 'academic degree'), ('obj', 'http://www.wikidata.org/entity/Q121594'), ('name', 'professor'), ('p2', 'http://www.wikidata.org/prop/direct/P2347'), ('namep2', 'YSO ID')]
# [('educationname', 'academic degree'), ('obj', 'http://www.wikidata.org/entity/Q1765120'), ('name', 'Bachelor of Arts'), ('p2', 'http://www.wikidata.org/prop/direct/P244'), ('namep2', 'Library of Congress authority ID')]
# [('educationname', 'educated at'), ('obj', 'http://www.wikidata.org/entity/Q73094'), ('name', "The Queen's College"), ('p2', 'http://www.wikidata.org/prop/direct/P244'), ('namep2', 'Library of Congress authority ID')]
# [('educationname', 'educated at'), ('obj', 'http://www.wikidata.org/entity/Q73094'), ('name', "The Queen's College"), ('p2', 'http://www.wikidata.org/prop/direct/P245'), ('namep2', 'Union List of Artist Names ID')]
# [('educationname', 'academic degree'), ('obj', 'http://www.wikidata.org/entity/Q121594'), ('name', 'professor'), ('p2', 'http://www.wikidata.org/prop/direct/P2581'), ('namep2', 'BabelNet ID')]
# [('educationname', 'educated at'), ('obj', 'http://www.wikidata.org/entity/Q73094'), ('name', "The Queen's College"), ('p2', 'http://www.wikidata.org/prop/direct/P276'), ('namep2', 'location')]
# [('educationname', 'educated at'), ('obj', 'http://www.wikidata.org/entity/Q5369138'), ('name', 'Emanuel School'), ('p2', 'http://www.wikidata.org/prop/direct/P276'), ('namep2', 'location')]
# [('educationname', 'academic degree'), ('obj', 'http://www.wikidata.org/entity/Q121594'), ('name', 'professor'), ('p2', 'http://www.wikidata.org/prop/direct/P279'), ('namep2', 'subclass of')]
# [('educationname', 'academic degree'), ('obj', 'http://www.wikidata.org/entity/Q1765120'), ('name', 'Bachelor of Arts'), ('p2', 'http://www.wikidata.org/prop/direct/P279'), ('namep2', 'subclass of')]
# [('educationname', 'educated at'), ('obj', 'http://www.wikidata.org/entity/Q73094'), ('name', "The Queen's College"), ('p2', 'http://www.wikidata.org/prop/direct/P281'), ('namep2', 'postal code')]
# [('educationname', 'educated at'), ('obj', 'http://www.wikidata.org/entity/Q5369138'), ('name', 'Emanuel School'), ('p2', 'http://www.wikidata.org/prop/direct/P281'), ('namep2', 'postal code')]
# [('educationname', 'academic degree'), ('obj', 'http://www.wikidata.org/entity/Q121594'), ('name', 'professor'), ('p2', 'http://www.wikidata.org/prop/direct/P31'), ('namep2', 'instance of')]
# [('educationname', 'academic degree'), ('obj', 'http://www.wikidata.org/entity/Q1765120'), ('name', 'Bachelor of Arts'), ('p2', 'http://www.wikidata.org/prop/direct/P31'), ('namep2', 'instance of')]
# [('educationname', 'educated at'), ('obj', 'http://www.wikidata.org/entity/Q73094'), ('name', "The Queen's College"), ('p2', 'http://www.wikidata.org/prop/direct/P31'), ('namep2', 'instance of')]
# [('educationname', 'educated at'), ('obj', 'http://www.wikidata.org/entity/Q5369138'), ('name', 'Emanuel School'), ('p2', 'http://www.wikidata.org/prop/direct/P31'), ('namep2', 'instance of')]
# [('educationname', 'educated at'), ('obj', 'http://www.wikidata.org/entity/Q73094'), ('name', "The Queen's College"), ('p2', 'http://www.wikidata.org/prop/direct/P3153'), ('namep2', 'Crossref funder ID')]
# [('educationname', 'academic degree'), ('obj', 'http://www.wikidata.org/entity/Q1765120'), ('name', 'Bachelor of Arts'), ('p2', 'http://www.wikidata.org/prop/direct/P3241'), ('namep2', 'Catholic Encyclopedia ID')]
# [('educationname', 'academic degree'), ('obj', 'http://www.wikidata.org/entity/Q1765120'), ('name', 'Bachelor of Arts'), ('p2', 'http://www.wikidata.org/prop/direct/P3417'), ('namep2', 'Quora topic ID')]
# [('educationname', 'educated at'), ('obj', 'http://www.wikidata.org/entity/Q73094'), ('name', "The Queen's College"), ('p2', 'http://www.wikidata.org/prop/direct/P3417'), ('namep2', 'Quora topic ID')]
# [('educationname', 'educated at'), ('obj', 'http://www.wikidata.org/entity/Q5369138'), ('name', 'Emanuel School'), ('p2', 'http://www.wikidata.org/prop/direct/P3417'), ('namep2', 'Quora topic ID')]
# [('educationname', 'educated at'), ('obj', 'http://www.wikidata.org/entity/Q73094'), ('name', "The Queen's College"), ('p2', 'http://www.wikidata.org/prop/direct/P3500'), ('namep2', 'Ringgold ID')]
# [('educationname', 'educated at'), ('obj', 'http://www.wikidata.org/entity/Q5369138'), ('name', 'Emanuel School'), ('p2', 'http://www.wikidata.org/prop/direct/P3500'), ('namep2', 'Ringgold ID')]
# [('educationname', 'academic degree'), ('obj', 'http://www.wikidata.org/entity/Q121594'), ('name', 'professor'), ('p2', 'http://www.wikidata.org/prop/direct/P3553'), ('namep2', 'Zhihu topic ID')]
# [('educationname', 'educated at'), ('obj', 'http://www.wikidata.org/entity/Q73094'), ('name', "The Queen's College"), ('p2', 'http://www.wikidata.org/prop/direct/P361'), ('namep2', 'part of')]
# [('educationname', 'academic degree'), ('obj', 'http://www.wikidata.org/entity/Q121594'), ('name', 'professor'), ('p2', 'http://www.wikidata.org/prop/direct/P373'), ('namep2', 'Commons category')]
# [('educationname', 'educated at'), ('obj', 'http://www.wikidata.org/entity/Q73094'), ('name', "The Queen's College"), ('p2', 'http://www.wikidata.org/prop/direct/P373'), ('namep2', 'Commons category')]
# [('educationname', 'educated at'), ('obj', 'http://www.wikidata.org/entity/Q5369138'), ('name', 'Emanuel School'), ('p2', 'http://www.wikidata.org/prop/direct/P3749'), ('namep2', 'Google Maps Customer ID')]
# [('educationname', 'educated at'), ('obj', 'http://www.wikidata.org/entity/Q73094'), ('name', "The Queen's College"), ('p2', 'http://www.wikidata.org/prop/direct/P3761'), ('namep2', 'IPv4 routing prefix')]
# [('educationname', 'educated at'), ('obj', 'http://www.wikidata.org/entity/Q73094'), ('name', "The Queen's College"), ('p2', 'http://www.wikidata.org/prop/direct/P3876'), ('namep2', 'category for alumni of educational institution')]
# [('educationname', 'educated at'), ('obj', 'http://www.wikidata.org/entity/Q5369138'), ('name', 'Emanuel School'), ('p2', 'http://www.wikidata.org/prop/direct/P3876'), ('namep2', 'category for alumni of educational institution')]
# [('educationname', 'academic degree'), ('obj', 'http://www.wikidata.org/entity/Q121594'), ('name', 'professor'), ('p2', 'http://www.wikidata.org/prop/direct/P3984'), ('namep2', 'subreddit')]
# [('educationname', 'educated at'), ('obj', 'http://www.wikidata.org/entity/Q73094'), ('name', "The Queen's College"), ('p2', 'http://www.wikidata.org/prop/direct/P4672'), ('namep2', 'EMLO location ID')]
# [('educationname', 'academic degree'), ('obj', 'http://www.wikidata.org/entity/Q1765120'), ('name', 'Bachelor of Arts'), ('p2', 'http://www.wikidata.org/prop/direct/P4839'), ('namep2', 'Wolfram Language entity code')]
# [('educationname', 'educated at'), ('obj', 'http://www.wikidata.org/entity/Q73094'), ('name', "The Queen's College"), ('p2', 'http://www.wikidata.org/prop/direct/P527'), ('namep2', 'has part')]
# [('educationname', 'educated at'), ('obj', 'http://www.wikidata.org/entity/Q73094'), ('name', "The Queen's College"), ('p2', 'http://www.wikidata.org/prop/direct/P571'), ('namep2', 'inception')]
# [('educationname', 'educated at'), ('obj', 'http://www.wikidata.org/entity/Q5369138'), ('name', 'Emanuel School'), ('p2', 'http://www.wikidata.org/prop/direct/P571'), ('namep2', 'inception')]
# [('educationname', 'academic degree'), ('obj', 'http://www.wikidata.org/entity/Q121594'), ('name', 'professor'), ('p2', 'http://www.wikidata.org/prop/direct/P6293'), ('namep2', 'YSA ID')]
# [('educationname', 'academic degree'), ('obj', 'http://www.wikidata.org/entity/Q121594'), ('name', 'professor'), ('p2', 'http://www.wikidata.org/prop/direct/P646'), ('namep2', 'Freebase ID')]
# [('educationname', 'academic degree'), ('obj', 'http://www.wikidata.org/entity/Q1765120'), ('name', 'Bachelor of Arts'), ('p2', 'http://www.wikidata.org/prop/direct/P646'), ('namep2', 'Freebase ID')]
# [('educationname', 'educated at'), ('obj', 'http://www.wikidata.org/entity/Q73094'), ('name', "The Queen's College"), ('p2', 'http://www.wikidata.org/prop/direct/P646'), ('namep2', 'Freebase ID')]
# [('educationname', 'educated at'), ('obj', 'http://www.wikidata.org/entity/Q5369138'), ('name', 'Emanuel School'), ('p2', 'http://www.wikidata.org/prop/direct/P646'), ('namep2', 'Freebase ID')]
# [('educationname', 'academic degree'), ('obj', 'http://www.wikidata.org/entity/Q121594'), ('name', 'professor'), ('p2', 'http://www.wikidata.org/prop/direct/P6573'), ('namep2', 'Klexikon article ID')]
# [('educationname', 'educated at'), ('obj', 'http://www.wikidata.org/entity/Q73094'), ('name', "The Queen's College"), ('p2', 'http://www.wikidata.org/prop/direct/P669'), ('namep2', 'located on street')]
# [('educationname', 'academic degree'), ('obj', 'http://www.wikidata.org/entity/Q121594'), ('name', 'professor'), ('p2', 'http://www.wikidata.org/prop/direct/P6900'), ('namep2', 'NicoNicoPedia ID')]
# [('educationname', 'educated at'), ('obj', 'http://www.wikidata.org/entity/Q73094'), ('name', "The Queen's College"), ('p2', 'http://www.wikidata.org/prop/direct/P691'), ('namep2', 'NKCR AUT ID')]
# [('educationname', 'educated at'), ('obj', 'http://www.wikidata.org/entity/Q73094'), ('name', "The Queen's College"), ('p2', 'http://www.wikidata.org/prop/direct/P749'), ('namep2', 'parent organization')]
# [('educationname', 'educated at'), ('obj', 'http://www.wikidata.org/entity/Q73094'), ('name', "The Queen's College"), ('p2', 'http://www.wikidata.org/prop/direct/P7859'), ('namep2', 'WorldCat Identities ID')]
# [('educationname', 'educated at'), ('obj', 'http://www.wikidata.org/entity/Q73094'), ('name', "The Queen's College"), ('p2', 'http://www.wikidata.org/prop/direct/P7959'), ('namep2', 'historic county')]
# [('educationname', 'educated at'), ('obj', 'http://www.wikidata.org/entity/Q5369138'), ('name', 'Emanuel School'), ('p2', 'http://www.wikidata.org/prop/direct/P7959'), ('namep2', 'historic county')]
# [('educationname', 'educated at'), ('obj', 'http://www.wikidata.org/entity/Q73094'), ('name', "The Queen's College"), ('p2', 'http://www.wikidata.org/prop/direct/P8168'), ('namep2', 'FactGrid item ID')]
# [('educationname', 'academic degree'), ('obj', 'http://www.wikidata.org/entity/Q121594'), ('name', 'professor'), ('p2', 'http://www.wikidata.org/prop/direct/P8408'), ('namep2', 'KBpedia ID')]
# [('educationname', 'academic degree'), ('obj', 'http://www.wikidata.org/entity/Q1765120'), ('name', 'Bachelor of Arts'), ('p2', 'http://www.wikidata.org/prop/direct/P8408'), ('namep2', 'KBpedia ID')]
# [('educationname', 'academic degree'), ('obj', 'http://www.wikidata.org/entity/Q121594'), ('name', 'professor'), ('p2', 'http://www.wikidata.org/prop/direct/P8519'), ('namep2', 'RKD thesaurus ID')]
# [('educationname', 'academic degree'), ('obj', 'http://www.wikidata.org/entity/Q121594'), ('name', 'professor'), ('p2', 'http://www.wikidata.org/prop/direct/P8540'), ('namep2', 'American Folklore Society Ethnographic Thesaurus ID')]
# [('educationname', 'educated at'), ('obj', 'http://www.wikidata.org/entity/Q73094'), ('name', "The Queen's College"), ('p2', 'http://www.wikidata.org/prop/direct/P856'), ('namep2', 'official website')]
# [('educationname', 'educated at'), ('obj', 'http://www.wikidata.org/entity/Q5369138'), ('name', 'Emanuel School'), ('p2', 'http://www.wikidata.org/prop/direct/P856'), ('namep2', 'official website')]
# [('educationname', 'academic degree'), ('obj', 'http://www.wikidata.org/entity/Q121594'), ('name', 'professor'), ('p2', 'http://www.wikidata.org/prop/direct/P8814'), ('namep2', 'WordNet 3.1 Synset ID')]
# [('educationname', 'academic degree'), ('obj', 'http://www.wikidata.org/entity/Q121594'), ('name', 'professor'), ('p2', 'http://www.wikidata.org/prop/direct/P910'), ('namep2', "topic's main category")]
# [('educationname', 'educated at'), ('obj', 'http://www.wikidata.org/entity/Q73094'), ('name', "The Queen's College"), ('p2', 'http://www.wikidata.org/prop/direct/P910'), ('namep2', "topic's main category")]
# [('educationname', 'educated at'), ('obj', 'http://www.wikidata.org/entity/Q73094'), ('name', "The Queen's College"), ('p2', 'http://www.wikidata.org/prop/direct/P935'), ('namep2', 'Commons gallery')]
# [('educationname', 'educated at'), ('obj', 'http://www.wikidata.org/entity/Q73094'), ('name', "The Queen's College"), ('p2', 'http://www.wikidata.org/prop/direct/P94'), ('namep2', 'coat of arms image')]
# [('educationname', 'academic degree'), ('obj', 'http://www.wikidata.org/entity/Q121594'), ('name', 'professor'), ('p2', 'http://www.wikidata.org/prop/direct/P973'), ('namep2', 'described at URL')]
# [('educationname', 'educated at'), ('obj', 'http://www.wikidata.org/entity/Q73094'), ('name', "The Queen's College"), ('p2', 'http://www.wikidata.org/prop/direct/P9756'), ('namep2', 'Schoenberg Database of Manuscripts name ID')]
# [('educationname', 'academic degree'), ('obj', 'http://www.wikidata.org/entity/Q1765120'), ('name', 'Bachelor of Arts'), ('p2', 'http://www.wikidata.org/prop/direct/P1027'), ('namep2', 'conferred by')]
# [('educationname', 'academic degree'), ('obj', 'http://www.wikidata.org/entity/Q121594'), ('name', 'professor'), ('p2', 'http://www.wikidata.org/prop/direct/P3730'), ('namep2', 'next higher rank')]
# [('educationname', 'academic degree'), ('obj', 'http://www.wikidata.org/entity/Q1765120'), ('name', 'Bachelor of Arts'), ('p2', 'http://www.wikidata.org/prop/direct/P3730'), ('namep2', 'next higher rank')]
# [('educationname', 'educated at'), ('obj', 'http://www.wikidata.org/entity/Q73094'), ('name', "The Queen's College"), ('p2', 'http://www.wikidata.org/prop/direct/P3642'), ('namep2', 'ARCHON code')]
# [('educationname', 'educated at'), ('obj', 'http://www.wikidata.org/entity/Q5369138'), ('name', 'Emanuel School'), ('p2', 'http://www.wikidata.org/prop/direct/P3642'), ('namep2', 'ARCHON code')]
# [('educationname', 'academic degree'), ('obj', 'http://www.wikidata.org/entity/Q121594'), ('name', 'professor'), ('p2', 'http://www.wikidata.org/prop/direct/P867'), ('namep2', 'ROME Occupation Code (v3)')]
# [('educationname', 'educated at'), ('obj', 'http://www.wikidata.org/entity/Q5369138'), ('name', 'Emanuel School'), ('p2', 'http://www.wikidata.org/prop/direct/P2253'), ('namep2', 'DfE URN')]
# [('educationname', 'educated at'), ('obj', 'http://www.wikidata.org/entity/Q5369138'), ('name', 'Emanuel School'), ('p2', 'http://www.wikidata.org/prop/direct/P4971'), ('namep2', 'UK Provider Reference Number')]
# [('educationname', 'educated at'), ('obj', 'http://www.wikidata.org/entity/Q73094'), ('name', "The Queen's College"), ('p2', 'http://www.wikidata.org/prop/direct/P8167'), ('namep2', 'WhatDoTheyKnow organisation ID')]
# 102

# %%
# aim: check if 'Bachelor of Arts' is maybe one of the possible degrees in some university
# result: we found that it's a bachelor's degree
queryString = """
SELECT DISTINCT ?obj ?name
WHERE {
   # bind something
   wd:Q1765120 wdt:P31 ?obj .
   # get the label
   # ?obj sc:name ?name .
}
LIMIT 200
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('obj', 'http://www.wikidata.org/entity/Q163727'), ('name', "bachelor's degree")]
# 1

# %%
# aim: check properties and objects related to 'bachelor's degree'
# result: we don't find anything particularly useful
queryString = """
SELECT DISTINCT ?p ?name ?obj ?objname
WHERE {
   # bind something
   wd:Q163727 ?p ?obj .
   # get the label
   # ?p sc:name ?name .
   # ?obj sc:name ?objname .
}
LIMIT 200
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P1889'), ('name', 'different from'), ('obj', 'http://www.wikidata.org/entity/Q749020'), ('objname', 'licentiate')]
# [('p', 'http://www.wikidata.org/prop/direct/P460'), ('name', 'said to be the same as'), ('obj', 'http://www.wikidata.org/entity/Q749020'), ('objname', 'licentiate')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('name', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q4838815'), ('objname', 'Bachelor of Music')]
# [('p', 'http://www.wikidata.org/prop/direct/P460'), ('name', 'said to be the same as'), ('obj', 'http://www.wikidata.org/entity/Q1054679'), ('objname', 'laurea')]
# [('p', 'http://www.wikidata.org/prop/direct/P1001'), ('name', 'applies to jurisdiction'), ('obj', 'http://www.wikidata.org/entity/Q145'), ('objname', 'United Kingdom')]
# [('p', 'http://www.wikidata.org/prop/direct/P1001'), ('name', 'applies to jurisdiction'), ('obj', 'http://www.wikidata.org/entity/Q16'), ('objname', 'Canada')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('name', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q1765120'), ('objname', 'Bachelor of Arts')]
# [('p', 'http://www.wikidata.org/prop/direct/P1343'), ('name', 'described by source'), ('obj', 'http://www.wikidata.org/entity/Q19180675'), ('objname', 'Small Brockhaus and Efron Encyclopedic Dictionary')]
# [('p', 'http://www.wikidata.org/prop/direct/P1343'), ('name', 'described by source'), ('obj', 'http://www.wikidata.org/entity/Q19211082'), ('objname', 'Orthodox Theological Encyclopedia')]
# [('p', 'http://www.wikidata.org/prop/direct/P1343'), ('name', 'described by source'), ('obj', 'http://www.wikidata.org/entity/Q19538713'), ('objname', 'Vlastenský slovník historický')]
# [('p', 'http://www.wikidata.org/prop/direct/P1343'), ('name', 'described by source'), ('obj', 'http://www.wikidata.org/entity/Q20078554'), ('objname', 'Great Soviet Encyclopedia (1926–1947)')]
# [('p', 'http://www.wikidata.org/prop/direct/P1343'), ('name', 'described by source'), ('obj', 'http://www.wikidata.org/entity/Q2041543'), ('objname', 'Ottův slovník naučný')]
# [('p', 'http://www.wikidata.org/prop/direct/P1343'), ('name', 'described by source'), ('obj', 'http://www.wikidata.org/entity/Q27680201'), ('objname', "Riemann's Music Dictionary (1901–1904)")]
# [('p', 'http://www.wikidata.org/prop/direct/P1001'), ('name', 'applies to jurisdiction'), ('obj', 'http://www.wikidata.org/entity/Q30'), ('objname', 'United States of America')]
# [('p', 'http://www.wikidata.org/prop/direct/P1343'), ('name', 'described by source'), ('obj', 'http://www.wikidata.org/entity/Q3181656'), ('objname', 'The Nuttall Encyclopædia')]
# [('p', 'http://www.wikidata.org/prop/direct/P1343'), ('name', 'described by source'), ('obj', 'http://www.wikidata.org/entity/Q602358'), ('objname', 'Brockhaus and Efron Encyclopedic Dictionary')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('name', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q787674'), ('objname', 'Bachelor of Science')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('name', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q18189'), ('objname', 'educational stage')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('name', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q189533'), ('objname', 'academic degree')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('name', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q798137'), ('objname', 'Bachelor of Laws')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('name', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q13948235'), ('objname', 'Bachelor of Medicine, Bachelor of Surgery')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('name', 'subclass of'), ('obj', 'http://www.wikidata.org/entity/Q3529618'), ('objname', 'academic title')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('name', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q4218455'), ('objname', 'qualification')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('name', 'subclass of'), ('obj', 'http://www.wikidata.org/entity/Q4218455'), ('objname', 'qualification')]
# [('p', 'http://www.wikidata.org/prop/direct/P1889'), ('name', 'different from'), ('obj', 'http://www.wikidata.org/entity/Q1901305'), ('objname', 'baccalaureate')]
# [('p', 'http://www.wikidata.org/prop/direct/P460'), ('name', 'said to be the same as'), ('obj', 'http://www.wikidata.org/entity/Q3238020'), ('objname', 'licence')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('name', 'subclass of'), ('obj', 'http://www.wikidata.org/entity/Q6008527'), ('objname', 'undergraduate degree')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('name', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q2878277'), ('objname', 'Bachelor of Fine Arts')]
# [('p', 'http://www.wikidata.org/prop/direct/P155'), ('name', 'follows'), ('obj', 'http://www.wikidata.org/entity/Q51864095'), ('objname', 'Junior Bachelor')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('name', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q2878189'), ('objname', 'Bachelor of Social Science')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('name', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q798129'), ('objname', 'Bachelor of Business Administration')]
# [('p', 'http://www.wikidata.org/prop/direct/P910'), ('name', "topic's main category"), ('obj', 'http://www.wikidata.org/entity/Q7131195'), ('objname', "Category:Bachelor's degrees")]
# 32

# %%
# aim: get all the objects and properties related to 'university teacher'
# result: we found some properties that might relate to a possible university class or instance
queryString = """
SELECT DISTINCT ?p ?name ?obj ?objname
WHERE {
   # bind something
   wd:Q1622272 ?p ?obj .
   # get the label
   # ?p sc:name ?name .
   # ?obj sc:name ?objname .
}
LIMIT 200
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P460'), ('name', 'said to be the same as'), ('obj', 'http://www.wikidata.org/entity/Q1569495'), ('objname', 'lecturer')]
# [('p', 'http://www.wikidata.org/prop/direct/P1889'), ('name', 'different from'), ('obj', 'http://www.wikidata.org/entity/Q5669847'), ('objname', 'assistant professor')]
# [('p', 'http://www.wikidata.org/prop/direct/P425'), ('name', 'field of this occupation'), ('obj', 'http://www.wikidata.org/entity/Q136822'), ('objname', 'higher education')]
# [('p', 'http://www.wikidata.org/prop/direct/P1889'), ('name', 'different from'), ('obj', 'http://www.wikidata.org/entity/Q121594'), ('objname', 'professor')]
# [('p', 'http://www.wikidata.org/prop/direct/P1889'), ('name', 'different from'), ('obj', 'http://www.wikidata.org/entity/Q28004591'), ('objname', 'professeur des universités')]
# [('p', 'http://www.wikidata.org/prop/direct/P1889'), ('name', 'different from'), ('obj', 'http://www.wikidata.org/entity/Q37226'), ('objname', 'teacher')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('name', 'subclass of'), ('obj', 'http://www.wikidata.org/entity/Q37226'), ('objname', 'teacher')]
# [('p', 'http://www.wikidata.org/prop/direct/P1889'), ('name', 'different from'), ('obj', 'http://www.wikidata.org/entity/Q25339110'), ('objname', 'full professor')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('name', 'subclass of'), ('obj', 'http://www.wikidata.org/entity/Q3400985'), ('objname', 'academic')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('name', 'subclass of'), ('obj', 'http://www.wikidata.org/entity/Q5428874'), ('objname', 'faculty member')]
# [('p', 'http://www.wikidata.org/prop/direct/P1889'), ('name', 'different from'), ('obj', 'http://www.wikidata.org/entity/Q1706722'), ('objname', 'research fellow')]
# [('p', 'http://www.wikidata.org/prop/direct/P425'), ('name', 'field of this occupation'), ('obj', 'http://www.wikidata.org/entity/Q352842'), ('objname', 'teaching')]
# [('p', 'http://www.wikidata.org/prop/direct/P1889'), ('name', 'different from'), ('obj', 'http://www.wikidata.org/entity/Q1914832'), ('objname', 'associate professor')]
# [('p', 'http://www.wikidata.org/prop/direct/P910'), ('name', "topic's main category"), ('obj', 'http://www.wikidata.org/entity/Q10175509'), ('objname', 'Category:University teachers')]
# [('p', 'http://www.wikidata.org/prop/direct/P1889'), ('name', 'different from'), ('obj', 'http://www.wikidata.org/entity/Q43632202'), ('objname', 'university demonstrator')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('name', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q66666607'), ('objname', 'academic profession')]
# 16

# %%
# aim: get all the objects and properties related to 'teacher' and 'academic'
# result: we did not find useful data
queryString = """
SELECT DISTINCT ?p ?name ?obj ?objname
WHERE {
   # bind something
   # ?s ?p ?obj .
   # get the label
   # ?p sc:name ?name .
   # ?obj sc:name ?objname .
   FILTER (?s IN (wd:Q37226, wd:Q3400985))
}
LIMIT 200
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P1343'), ('name', 'described by source'), ('obj', 'http://www.wikidata.org/entity/Q106727050'), ('objname', 'Metropolitan Museum of Art Tagging Vocabulary')]
# [('p', 'http://www.wikidata.org/prop/direct/P1889'), ('name', 'different from'), ('obj', 'http://www.wikidata.org/entity/Q1231865'), ('objname', 'pedagogue')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('name', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q12737077'), ('objname', 'occupation')]
# [('p', 'http://www.wikidata.org/prop/direct/P1889'), ('name', 'different from'), ('obj', 'http://www.wikidata.org/entity/Q1622272'), ('objname', 'university teacher')]
# [('p', 'http://www.wikidata.org/prop/direct/P1343'), ('name', 'described by source'), ('obj', 'http://www.wikidata.org/entity/Q19180675'), ('objname', 'Small Brockhaus and Efron Encyclopedic Dictionary')]
# [('p', 'http://www.wikidata.org/prop/direct/P1343'), ('name', 'described by source'), ('obj', 'http://www.wikidata.org/entity/Q2041543'), ('objname', 'Ottův slovník naučný')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('name', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q28640'), ('objname', 'profession')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('name', 'subclass of'), ('obj', 'http://www.wikidata.org/entity/Q37226'), ('objname', 'teacher')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('name', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q4164871'), ('objname', 'position')]
# [('p', 'http://www.wikidata.org/prop/direct/P461'), ('name', 'opposite of'), ('obj', 'http://www.wikidata.org/entity/Q48282'), ('objname', 'student')]
# [('p', 'http://www.wikidata.org/prop/direct/P1343'), ('name', 'described by source'), ('obj', 'http://www.wikidata.org/entity/Q602358'), ('objname', 'Brockhaus and Efron Encyclopedic Dictionary')]
# [('p', 'http://www.wikidata.org/prop/direct/P425'), ('name', 'field of this occupation'), ('obj', 'http://www.wikidata.org/entity/Q8434'), ('objname', 'education')]
# [('p', 'http://www.wikidata.org/prop/direct/P1889'), ('name', 'different from'), ('obj', 'http://www.wikidata.org/entity/Q414528'), ('objname', 'academician')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('name', 'subclass of'), ('obj', 'http://www.wikidata.org/entity/Q2248623'), ('objname', 'scholar')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('name', 'subclass of'), ('obj', 'http://www.wikidata.org/entity/Q974144'), ('objname', 'educator')]
# [('p', 'http://www.wikidata.org/prop/direct/P460'), ('name', 'said to be the same as'), ('obj', 'http://www.wikidata.org/entity/Q1706722'), ('objname', 'research fellow')]
# [('p', 'http://www.wikidata.org/prop/direct/P425'), ('name', 'field of this occupation'), ('obj', 'http://www.wikidata.org/entity/Q352842'), ('objname', 'teaching')]
# [('p', 'http://www.wikidata.org/prop/direct/P461'), ('name', 'opposite of'), ('obj', 'http://www.wikidata.org/entity/Q253567'), ('objname', 'apprentice')]
# [('p', 'http://www.wikidata.org/prop/direct/P910'), ('name', "topic's main category"), ('obj', 'http://www.wikidata.org/entity/Q7014389'), ('objname', 'Category:Educators')]
# [('p', 'http://www.wikidata.org/prop/direct/P1687'), ('name', 'Wikidata property'), ('obj', 'http://www.wikidata.org/entity/P1066'), ('objname', 'student of')]
# [('p', 'http://www.wikidata.org/prop/direct/P361'), ('name', 'part of'), ('obj', 'http://www.wikidata.org/entity/Q1211427'), ('objname', 'academia')]
# [('p', 'http://www.wikidata.org/prop/direct/P910'), ('name', "topic's main category"), ('obj', 'http://www.wikidata.org/entity/Q6177034'), ('objname', 'Category:Academics')]
# [('p', 'http://www.wikidata.org/prop/direct/P461'), ('name', 'opposite of'), ('obj', 'http://www.wikidata.org/entity/Q11448873'), ('objname', 'learner')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('name', 'subclass of'), ('obj', 'http://www.wikidata.org/entity/Q108284914'), ('objname', 'teaching professionals')]
# [('p', 'http://www.wikidata.org/prop/direct/P1889'), ('name', 'different from'), ('obj', 'http://www.wikidata.org/entity/Q15966880'), ('objname', 'Pedagóg')]
# [('p', 'http://www.wikidata.org/prop/direct/P1424'), ('name', "topic's main template"), ('obj', 'http://www.wikidata.org/entity/Q13476663'), ('objname', 'Template:Infobox academic')]
# [('p', 'http://www.wikidata.org/prop/direct/P4195'), ('name', 'category for employees of the organization'), ('obj', 'http://www.wikidata.org/entity/Q15305113'), ('objname', "Category:Academics of Saint Martin's School of Art")]
# 27

# %%
# aim: get all the entities related to 'university teacher'
# result: we found some university teachers that can be used to get other data
queryString = """
SELECT DISTINCT ?s ?sname ?p ?name
WHERE {
   # bind something
   # ?s ?p wd:Q1622272 .
   # get the label
   # ?p sc:name ?name .
   # ?s sc:name ?sname .
}
LIMIT 200
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('s', 'http://www.wikidata.org/entity/Q28475249'), ('sname', 'Joaquín Garrigues Díaz-Cañabate'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q8166543'), ('sname', 'Hajo Bernett'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q8190500'), ('sname', 'Seinosuke Toda'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q8194957'), ('sname', 'Alexandre Azedo Lacerda'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q8196240'), ('sname', 'Alois Richard Nykl'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q8201210'), ('sname', 'Antonio Escohotado'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q105319'), ('sname', 'Helmut Herbst'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q293218'), ('sname', 'Joan Tower'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q357316'), ('sname', 'Dušan Makavejev'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q507813'), ('sname', 'György Pálfi'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q57257'), ('sname', 'Peter Cornelius'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q63986960'), ('sname', 'Wang Xiaodun'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q674739'), ('sname', 'Alexander Mackenzie'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q8463086'), ('sname', "Chang Ch'ung-ho"), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q159967'), ('sname', 'Augusto Roa Bastos'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q13724705'), ('sname', 'Henriëtte Prast'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q71035'), ('sname', 'August Ritter'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q15456944'), ('sname', 'Franz Stadtmüller'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q15457042'), ('sname', 'Michel Clement'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q15457045'), ('sname', 'Ronald Schettkat'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q15457101'), ('sname', 'Ferdinand Eichwede'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q15457305'), ('sname', 'Bodo Spiethoff'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q15457309'), ('sname', 'Dietrich Knorr'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q15461480'), ('sname', 'Ian Carr-Harris'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q15477158'), ('sname', 'Sieglinde Hartmann'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q15479681'), ('sname', 'Wolfram Jäger'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q15479896'), ('sname', 'Hans Stumpfeldt'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q15479916'), ('sname', 'Tillmann Loch'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q15479939'), ('sname', 'Friedrich Kummer'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q15479980'), ('sname', 'Rolf Ludwig'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q15480173'), ('sname', 'Vladimir Scheffer'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q15487646'), ('sname', 'Ivy Williams'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q15488137'), ('sname', 'Ernst Giese'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q15489129'), ('sname', 'Robert Elgie'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q2379920'), ('sname', 'Sönke Albers'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q370878'), ('sname', 'Paul Patterson'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q614454'), ('sname', 'Efrem Zimbalist'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q1029943'), ('sname', 'Julius Dedekind'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q109716'), ('sname', 'Peter-Alexis Albrecht'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q12383167'), ('sname', 'Anxo Tarrío Varela'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q12817'), ('sname', 'Probal Dasgupta'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q1515807'), ('sname', 'Yehuda Shoenfeld'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q15727271'), ('sname', 'Alvydas Baležentis'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q15728166'), ('sname', 'Andrzej Jerzy Zglejszewski'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q15732913'), ('sname', 'Gabrielle Oberhänsli-Widmer'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q15733170'), ('sname', 'Karl Schering'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q15733264'), ('sname', 'Horst H. Berger'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q15734379'), ('sname', 'Fabio Fabene'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q167048'), ('sname', 'Ieke Moerdijk'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q18634148'), ('sname', 'Mary Nash'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q21043270'), ('sname', 'Martha A. Derthick'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q21281119'), ('sname', 'Ramon Garrabou i Segura'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q213675'), ('sname', 'Gottfried August Bürger'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q213996'), ('sname', 'Raymond Klibansky'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q2536731'), ('sname', 'W. Maxwell Cowan'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q27831074'), ('sname', 'Marcus Munafo'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q2919282'), ('sname', 'Randolph L. Braham'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q30525400'), ('sname', 'Marta Olivetti Belardinelli'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q3184124'), ('sname', 'Josep Termes i Ardèvol'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q361222'), ('sname', 'Adolf Dedekind'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q5560581'), ('sname', 'Gil Omenn'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q5795846'), ('sname', 'Cándida Martínez López'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q6759639'), ('sname', 'Margaret Levi'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q85830658'), ('sname', 'Griffin Murray'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q9012158'), ('sname', 'Joaquim Molas'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q92669'), ('sname', 'Jeffrey Shallit'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q93237853'), ('sname', 'Jean-Michel Rabaté'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q104327'), ('sname', 'Otto Rossbach'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q1117778'), ('sname', 'Leo Moser'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q111925'), ('sname', 'Helmut Wielandt'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q115448'), ('sname', 'Daniel Bovet'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q1222685'), ('sname', 'Dieter Richter'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q1226358'), ('sname', 'Ding Shisun'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q1459262'), ('sname', 'Friedrich Glasl'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q1466522'), ('sname', 'Fritz Haller'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q15054444'), ('sname', 'Ignat Florian Bociort'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q15428150'), ('sname', 'Klaus Mackscheidt'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q1561150'), ('sname', 'Günter Ulbert'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q15842875'), ('sname', 'Roland Bässler'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q15843901'), ('sname', 'Samuel Bansovius'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q15849004'), ('sname', 'Stefan L. Brandt'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q15849145'), ('sname', 'Stephan Freiger'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q15850696'), ('sname', 'Thilo Ulbert'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q15850811'), ('sname', 'Thomas Steger'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q15850824'), ('sname', 'Thomas William Allen'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q15850986'), ('sname', 'Timoteus Pokora'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q15853481'), ('sname', 'Walter A. Friedman'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q15853515'), ('sname', 'Walter Henzen'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q15853540'), ('sname', 'Walter Methlagl'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q15854508'), ('sname', 'Wilhelm Lange'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q15854550'), ('sname', 'Wilhelm Theopold'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q15855013'), ('sname', 'Wolfgang Keim'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q15857659'), ('sname', 'Fredos Papangelou'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q15858590'), ('sname', 'Heidemarie Uhl'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q15858644'), ('sname', 'Helmut Krueger'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q15858730'), ('sname', 'Horst Remane'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q15859185'), ('sname', 'Jirka Dell’Oro-Friedl'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q15859787'), ('sname', 'Kurt Meyer'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q15867617'), ('sname', 'Ramūnas Kalvaitis'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q15867843'), ('sname', 'Stefan Oster'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q15867936'), ('sname', 'Vitus Müller'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q15868353'), ('sname', 'Aalt Bast'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q15875075'), ('sname', 'Evert Aardema'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q15875407'), ('sname', 'François Schollaert'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q15876182'), ('sname', 'Henc van Maarseveen'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q15876792'), ('sname', 'Jaap van der Gouw'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q15876975'), ('sname', 'Jean Marquet'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q15877383'), ('sname', 'Kees Damsteegt'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q15880598'), ('sname', 'Pauline Wiertz'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q15881197'), ('sname', 'Reinhold Hoppe'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q15881374'), ('sname', 'Roel van Duin'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q15882859'), ('sname', 'Thom Bezembinder'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q15893914'), ('sname', 'Christina Aus der Au Heymann'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q15900159'), ('sname', 'David A. B. Miller'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q15905670'), ('sname', 'Birgit Schenk'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q15905868'), ('sname', 'Charlotte Schulze'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q15906413'), ('sname', 'Frank Henry Stubbings'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q15906773'), ('sname', 'Heinrich Welling'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q15907113'), ('sname', 'Jonathan P. Heritage'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q15907132'), ('sname', 'Jörg Meuthen'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q15907232'), ('sname', 'Klaus Locher'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q15917430'), ('sname', 'A. Ollongren'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q1610324'), ('sname', 'Herman Philipse'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q16946457'), ('sname', 'Ann-Sofie Söderqvist'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q20202960'), ('sname', 'François Donny jr.'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q2521964'), ('sname', 'Vicente Jarque'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q2961205'), ('sname', 'Ton Venhoeven'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q340426'), ('sname', 'Achim Lichtenberger'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q43930'), ('sname', 'Reinhard Marx'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q45172'), ('sname', 'Alois Kothgasser'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q50821934'), ('sname', 'Aerdt Houben'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q71490'), ('sname', 'Ulrich Wickert'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q72860'), ('sname', 'Gustav Hirschfeld'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q7585560'), ('sname', 'Warren Ambrose'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q10294926'), ('sname', 'Henry Louis Langhaar'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q105219'), ('sname', 'Ferdinand Gottlieb von Gmelin'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q106751'), ('sname', 'Alan J. Heeger'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q1454372'), ('sname', 'Max Ihm'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q1525850'), ('sname', 'alireza tito'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q15821081'), ('sname', 'Joan Campbell'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q1585395'), ('sname', 'Harish-Chandra'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q16006172'), ('sname', 'Max-Reinhard Felde'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q16006191'), ('sname', 'Herbert Kienzler'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q16010796'), ('sname', 'Jürgen C. Aschoff'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q16013075'), ('sname', 'J. Wayne Reitz'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q16013087'), ('sname', 'Aaron Scharf'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q16019097'), ('sname', 'McAllister Hull'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q16019710'), ('sname', 'Max Howell'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q16027676'), ('sname', 'Jean-Jacques Eledjam'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q16027737'), ('sname', 'John Alexander Simpson'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q16027814'), ('sname', 'Bernard Poujade'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q16027821'), ('sname', 'Claude Rouiller'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q16031879'), ('sname', 'Aimé-Georges Martimort'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q16039483'), ('sname', 'Arias Barbosa'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q16050812'), ('sname', 'Gaston Basalgas'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q16054275'), ('sname', 'Alexander Knuth'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q16054370'), ('sname', 'Andreas Gutsfeld'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q16054937'), ('sname', 'Seweryn Ajzner'), ('p', 'http://www.wikidata.org/prop/direct/P101'), ('name', 'field of work')]
# [('s', 'http://www.wikidata.org/entity/Q16061199'), ('sname', 'Christiane Spiel'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q16062010'), ('sname', 'Spiridon Manginas'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q16062015'), ('sname', 'Chrysostomos Mantzavinos'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q16062099'), ('sname', 'Aikaterínī Christofilopoúlou'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q16063179'), ('sname', 'Thomas Osmond Summers'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q16063675'), ('sname', 'Ergin Sezgin'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q16064291'), ('sname', 'Paul Lacroix'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q16064498'), ('sname', 'Franziska Jundt'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q16064534'), ('sname', 'Friedrich Reinhard Schmidt'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q16064694'), ('sname', 'Gerhard Hanswille'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q16069692'), ('sname', 'Luc Sels'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q16070285'), ('sname', 'Daniël Vandepitte'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q16070582'), ('sname', 'Philip Kleintjes'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q2553060'), ('sname', 'Wayne Fuller'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q28105192'), ('sname', 'Dimitris Michalopoulos'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q3271808'), ('sname', 'Léopold Genicot'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q5199552'), ('sname', 'Cornelis Kalkman'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q5566413'), ('sname', 'Charles Francis Bastable'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q574603'), ('sname', 'Paul-André Meyer'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q63334'), ('sname', 'Christian Gmelin'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q96558'), ('sname', 'François-René Gebauer'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q12110383'), ('sname', 'Aleksandr Burmov'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q16170994'), ('sname', 'Talina Herasymova'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q16178185'), ('sname', 'Arie Cornelis Bouman'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q16186116'), ('sname', 'Wolfgang Schultze'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q16186128'), ('sname', 'Pierre Lafabrie'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q16187150'), ('sname', 'Muhammad Farooq Khan'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q16188695'), ('sname', 'Ciro Llueca i Fonollosa'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q16188991'), ('sname', 'Josep Coll i Bertran'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q16189752'), ('sname', 'Joan Connelly Ullman'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q16191436'), ('sname', 'Miquel Duran Pastor'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q16193471'), ('sname', 'David Berry'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q16195365'), ('sname', 'Tracy Mackenna'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q16198181'), ('sname', 'Clyde Pharr'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q16205796'), ('sname', 'Jack Cottrell'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q16211514'), ('sname', 'Haruna Iddrisu'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q16214347'), ('sname', 'Michael Blanton'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q16215654'), ('sname', 'Jan Gummert'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q16215963'), ('sname', 'Johan Frederik Lodewijk Schröder'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q16216175'), ('sname', 'Joseph Penzien'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q16216372'), ('sname', 'Klaus Ernst'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('s', 'http://www.wikidata.org/entity/Q16216373'), ('sname', 'Klaus Fuchs-Kittowski'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# 200

# %%
# aim: at this point we try again following the path from the 'Emanuel's school' and 'Queens College' related to Tim Berner's Lee
# result: we found the University Of Oxford! Maybe now we can retrieve the University of Cambridge and get the list of professors who worked there!
queryString = """
SELECT DISTINCT ?s ?p ?name ?obj ?objname
WHERE {
   # bind something
   # ?s ?p ?obj .
   # get the label
   # ?p sc:name ?name .
   # ?obj sc:name ?objname .
   FILTER (?s IN (wd:Q5369138,wd:Q73094))
}
LIMIT 200
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('s', 'http://www.wikidata.org/entity/Q5369138'), ('p', 'http://www.wikidata.org/prop/direct/P112'), ('name', 'founded by'), ('obj', 'http://www.wikidata.org/entity/Q4768325'), ('objname', 'Anne Fiennes')]
# [('s', 'http://www.wikidata.org/entity/Q5369138'), ('p', 'http://www.wikidata.org/prop/direct/P140'), ('name', 'religion'), ('obj', 'http://www.wikidata.org/entity/Q106039'), ('objname', 'Christian')]
# [('s', 'http://www.wikidata.org/entity/Q73094'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('name', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q19844914'), ('objname', 'university building')]
# [('s', 'http://www.wikidata.org/entity/Q73094'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('name', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q2581649'), ('objname', 'college of the University of Oxford')]
# [('s', 'http://www.wikidata.org/entity/Q5369138'), ('p', 'http://www.wikidata.org/prop/direct/P131'), ('name', 'located in the administrative territorial entity'), ('obj', 'http://www.wikidata.org/entity/Q210563'), ('objname', 'London Borough of Wandsworth')]
# [('s', 'http://www.wikidata.org/entity/Q5369138'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('name', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q2418495'), ('objname', 'independent school')]
# [('s', 'http://www.wikidata.org/entity/Q73094'), ('p', 'http://www.wikidata.org/prop/direct/P17'), ('name', 'country'), ('obj', 'http://www.wikidata.org/entity/Q145'), ('objname', 'United Kingdom')]
# [('s', 'http://www.wikidata.org/entity/Q5369138'), ('p', 'http://www.wikidata.org/prop/direct/P17'), ('name', 'country'), ('obj', 'http://www.wikidata.org/entity/Q145'), ('objname', 'United Kingdom')]
# [('s', 'http://www.wikidata.org/entity/Q73094'), ('p', 'http://www.wikidata.org/prop/direct/P276'), ('name', 'location'), ('obj', 'http://www.wikidata.org/entity/Q34217'), ('objname', 'Oxford')]
# [('s', 'http://www.wikidata.org/entity/Q73094'), ('p', 'http://www.wikidata.org/prop/direct/P361'), ('name', 'part of'), ('obj', 'http://www.wikidata.org/entity/Q34433'), ('objname', 'University of Oxford')]
# [('s', 'http://www.wikidata.org/entity/Q73094'), ('p', 'http://www.wikidata.org/prop/direct/P749'), ('name', 'parent organization'), ('obj', 'http://www.wikidata.org/entity/Q34433'), ('objname', 'University of Oxford')]
# [('s', 'http://www.wikidata.org/entity/Q5369138'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('name', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q3914'), ('objname', 'school')]
# [('s', 'http://www.wikidata.org/entity/Q5369138'), ('p', 'http://www.wikidata.org/prop/direct/P276'), ('name', 'location'), ('obj', 'http://www.wikidata.org/entity/Q84'), ('objname', 'London')]
# [('s', 'http://www.wikidata.org/entity/Q73094'), ('p', 'http://www.wikidata.org/prop/direct/P131'), ('name', 'located in the administrative territorial entity'), ('obj', 'http://www.wikidata.org/entity/Q20986484'), ('objname', 'Oxford')]
# [('s', 'http://www.wikidata.org/entity/Q73094'), ('p', 'http://www.wikidata.org/prop/direct/P7959'), ('name', 'historic county'), ('obj', 'http://www.wikidata.org/entity/Q67311417'), ('objname', 'Oxfordshire')]
# [('s', 'http://www.wikidata.org/entity/Q73094'), ('p', 'http://www.wikidata.org/prop/direct/P527'), ('name', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q26650971'), ('objname', 'The Queens College, Terrace Outside The Library')]
# [('s', 'http://www.wikidata.org/entity/Q73094'), ('p', 'http://www.wikidata.org/prop/direct/P527'), ('name', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q26650972'), ('objname', 'The Queens College, Brewhouse')]
# [('s', 'http://www.wikidata.org/entity/Q5369138'), ('p', 'http://www.wikidata.org/prop/direct/P7959'), ('name', 'historic county'), ('obj', 'http://www.wikidata.org/entity/Q67443130'), ('objname', 'Surrey')]
# [('s', 'http://www.wikidata.org/entity/Q73094'), ('p', 'http://www.wikidata.org/prop/direct/P138'), ('name', 'named after'), ('obj', 'http://www.wikidata.org/entity/Q229279'), ('objname', 'Philippa of Hainault')]
# [('s', 'http://www.wikidata.org/entity/Q73094'), ('p', 'http://www.wikidata.org/prop/direct/P527'), ('name', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q17528383'), ('objname', 'The Queens College, North Range, Front Quadrangle (including Hall And Chapel)')]
# [('s', 'http://www.wikidata.org/entity/Q73094'), ('p', 'http://www.wikidata.org/prop/direct/P669'), ('name', 'located on street'), ('obj', 'http://www.wikidata.org/entity/Q60282'), ('objname', 'High Street')]
# [('s', 'http://www.wikidata.org/entity/Q5369138'), ('p', 'http://www.wikidata.org/prop/direct/P3876'), ('name', 'category for alumni of educational institution'), ('obj', 'http://www.wikidata.org/entity/Q15286098'), ('objname', 'Category:People educated at Emanuel School')]
# [('s', 'http://www.wikidata.org/entity/Q73094'), ('p', 'http://www.wikidata.org/prop/direct/P112'), ('name', 'founded by'), ('obj', 'http://www.wikidata.org/entity/Q7351397'), ('objname', 'Robert de Eglesfield')]
# [('s', 'http://www.wikidata.org/entity/Q73094'), ('p', 'http://www.wikidata.org/prop/direct/P527'), ('name', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q17528338'), ('objname', 'The Queens College, West Range, Back Quadrangle')]
# [('s', 'http://www.wikidata.org/entity/Q73094'), ('p', 'http://www.wikidata.org/prop/direct/P527'), ('name', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q17528379'), ('objname', 'The Queens College, West Range, Front Quadrangle')]
# [('s', 'http://www.wikidata.org/entity/Q73094'), ('p', 'http://www.wikidata.org/prop/direct/P527'), ('name', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q17528387'), ('objname', 'The Queens College, East Range, Front Quadrangle')]
# [('s', 'http://www.wikidata.org/entity/Q73094'), ('p', 'http://www.wikidata.org/prop/direct/P527'), ('name', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q17528544'), ('objname', 'The Queens College, South Range, Front Quadrangle')]
# [('s', 'http://www.wikidata.org/entity/Q73094'), ('p', 'http://www.wikidata.org/prop/direct/P527'), ('name', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q17528564'), ('objname', 'The Queens College, East Range, Back Quadrangle')]
# [('s', 'http://www.wikidata.org/entity/Q73094'), ('p', 'http://www.wikidata.org/prop/direct/P527'), ('name', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q17528819'), ('objname', 'The Queens College, North Range, Back Quadrangle')]
# [('s', 'http://www.wikidata.org/entity/Q73094'), ('p', 'http://www.wikidata.org/prop/direct/P527'), ('name', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q26298781'), ('objname', 'The Queens College, Fountain In Back Court')]
# [('s', 'http://www.wikidata.org/entity/Q73094'), ('p', 'http://www.wikidata.org/prop/direct/P527'), ('name', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q26298782'), ('objname', 'The Queens College, Walls Lining The Lane Leading From The Back Quadrangle To The Brewhouse')]
# [('s', 'http://www.wikidata.org/entity/Q73094'), ('p', 'http://www.wikidata.org/prop/direct/P527'), ('name', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q26298783'), ('objname', 'The Queens College, Drawda Hall')]
# [('s', 'http://www.wikidata.org/entity/Q73094'), ('p', 'http://www.wikidata.org/prop/direct/P527'), ('name', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q26298784'), ('objname', 'The Queens College, Boundary Wall On Queens Lane To West Of Library')]
# [('s', 'http://www.wikidata.org/entity/Q73094'), ('p', 'http://www.wikidata.org/prop/direct/P527'), ('name', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q26299163'), ('objname', 'The Queens College, Provosts Lodgings')]
# [('s', 'http://www.wikidata.org/entity/Q73094'), ('p', 'http://www.wikidata.org/prop/direct/P527'), ('name', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q26650973'), ('objname', 'The Queens College, Boundary Wall On Queens Lane Adjoining The Chapel')]
# [('s', 'http://www.wikidata.org/entity/Q73094'), ('p', 'http://www.wikidata.org/prop/direct/P527'), ('name', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q26672392'), ('objname', 'Florey Building')]
# [('s', 'http://www.wikidata.org/entity/Q73094'), ('p', 'http://www.wikidata.org/prop/direct/P527'), ('name', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q56183154'), ('objname', "Queen's College Library")]
# [('s', 'http://www.wikidata.org/entity/Q73094'), ('p', 'http://www.wikidata.org/prop/direct/P3876'), ('name', 'category for alumni of educational institution'), ('obj', 'http://www.wikidata.org/entity/Q8237218'), ('objname', "Category:Alumni of The Queen's College, Oxford")]
# [('s', 'http://www.wikidata.org/entity/Q73094'), ('p', 'http://www.wikidata.org/prop/direct/P910'), ('name', "topic's main category"), ('obj', 'http://www.wikidata.org/entity/Q8849341'), ('objname', "Category:The Queen's College, Oxford")]
# [('s', 'http://www.wikidata.org/entity/Q73094'), ('p', 'http://www.wikidata.org/prop/direct/P527'), ('name', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q17528860'), ('objname', 'The Queens College, South Range, Back Quadrangle')]
# 40

# %%
# aim: get all the properties and objects related to 'University of Oxford'
# result: we found the object 'public university' and 'higher education institution' so maybe the 'University of Cambridge' is an instance of them
queryString = """
SELECT DISTINCT ?p ?name ?obj ?objname
WHERE {
   # bind something
   wd:Q34433 ?p ?obj .
   # get the label
   # ?p sc:name ?name .
   # ?obj sc:name ?objname .
}
LIMIT 200
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P3876'), ('name', 'category for alumni of educational institution'), ('obj', 'http://www.wikidata.org/entity/Q8237442'), ('objname', 'Category:Alumni of the University of Oxford')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('name', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q128497'), ('objname', "St Hugh's College")]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('name', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q2035359'), ('objname', "St Antony's College")]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('name', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q5273413'), ('objname', "St Stephen's House")]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('name', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q1546625'), ('objname', 'Griffith Institute')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('name', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q73094'), ('objname', "The Queen's College")]
# [('p', 'http://www.wikidata.org/prop/direct/P1830'), ('name', 'owner of'), ('obj', 'http://www.wikidata.org/entity/Q16994716'), ('objname', 'Iffley Road rugby football ground')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('name', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q3354859'), ('objname', 'collegiate university')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('name', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q81170'), ('objname', 'Oriel College')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('name', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q1247550'), ('objname', 'St Cross College')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('name', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q81174'), ('objname', 'Jesus College')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('name', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q82513'), ('objname', 'Merton College')]
# [('p', 'http://www.wikidata.org/prop/direct/P1830'), ('name', 'owner of'), ('obj', 'http://www.wikidata.org/entity/Q217595'), ('objname', 'Oxford University Press')]
# [('p', 'http://www.wikidata.org/prop/direct/P355'), ('name', 'subsidiary'), ('obj', 'http://www.wikidata.org/entity/Q217595'), ('objname', 'Oxford University Press')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('name', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q81090'), ('objname', 'Hertford College')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('name', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q1135137'), ('objname', 'Corpus Christi College')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('name', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q1465651'), ('objname', "St Hilda's College")]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('name', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q73079'), ('objname', 'Trinity College')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('name', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q82606'), ('objname', 'Pembroke College')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('name', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q1758457'), ('objname', 'Nuffield College')]
# [('p', 'http://www.wikidata.org/prop/direct/P463'), ('name', 'member of'), ('obj', 'http://www.wikidata.org/entity/Q105077092'), ('objname', 'Shibboleth Consortium')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('name', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q3402788'), ('objname', 'Wycliffe Hall')]
# [('p', 'http://www.wikidata.org/prop/direct/P17'), ('name', 'country'), ('obj', 'http://www.wikidata.org/entity/Q145'), ('objname', 'United Kingdom')]
# [('p', 'http://www.wikidata.org/prop/direct/P2936'), ('name', 'language used'), ('obj', 'http://www.wikidata.org/entity/Q1860'), ('objname', 'English')]
# [('p', 'http://www.wikidata.org/prop/direct/P463'), ('name', 'member of'), ('obj', 'http://www.wikidata.org/entity/Q19861084'), ('objname', 'ORCID, Inc.')]
# [('p', 'http://www.wikidata.org/prop/direct/P421'), ('name', 'located in time zone'), ('obj', 'http://www.wikidata.org/entity/Q30192'), ('objname', 'Greenwich Mean Time')]
# [('p', 'http://www.wikidata.org/prop/direct/P1343'), ('name', 'described by source'), ('obj', 'http://www.wikidata.org/entity/Q3181656'), ('objname', 'The Nuttall Encyclopædia')]
# [('p', 'http://www.wikidata.org/prop/direct/P131'), ('name', 'located in the administrative territorial entity'), ('obj', 'http://www.wikidata.org/entity/Q34217'), ('objname', 'Oxford')]
# [('p', 'http://www.wikidata.org/prop/direct/P159'), ('name', 'headquarters location'), ('obj', 'http://www.wikidata.org/entity/Q34217'), ('objname', 'Oxford')]
# [('p', 'http://www.wikidata.org/prop/direct/P276'), ('name', 'location'), ('obj', 'http://www.wikidata.org/entity/Q34217'), ('objname', 'Oxford')]
# [('p', 'http://www.wikidata.org/prop/direct/P463'), ('name', 'member of'), ('obj', 'http://www.wikidata.org/entity/Q37033'), ('objname', 'World Wide Web Consortium')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('name', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q45400320'), ('objname', 'open-access publisher')]
# [('p', 'http://www.wikidata.org/prop/direct/P463'), ('name', 'member of'), ('obj', 'http://www.wikidata.org/entity/Q5275956'), ('objname', 'Digital Preservation Coalition')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('name', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q609646'), ('objname', "St John's College")]
# [('p', 'http://www.wikidata.org/prop/direct/P355'), ('name', 'subsidiary'), ('obj', 'http://www.wikidata.org/entity/Q774489'), ('objname', 'Somerville College')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('name', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q774489'), ('objname', 'Somerville College')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('name', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q805285'), ('objname', 'Balliol College')]
# [('p', 'http://www.wikidata.org/prop/direct/P355'), ('name', 'subsidiary'), ('obj', 'http://www.wikidata.org/entity/Q81162'), ('objname', 'Magdalen College')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('name', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q81162'), ('objname', 'Magdalen College')]
# [('p', 'http://www.wikidata.org/prop/direct/P276'), ('name', 'location'), ('obj', 'http://www.wikidata.org/entity/Q23169'), ('objname', 'Oxfordshire')]
# [('p', 'http://www.wikidata.org/prop/direct/P463'), ('name', 'member of'), ('obj', 'http://www.wikidata.org/entity/Q35677307'), ('objname', 'IIIF Consortium')]
# [('p', 'http://www.wikidata.org/prop/direct/P7959'), ('name', 'historic county'), ('obj', 'http://www.wikidata.org/entity/Q67311417'), ('objname', 'Oxfordshire')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('name', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q973884'), ('objname', 'St Edmund Hall')]
# [('p', 'http://www.wikidata.org/prop/direct/P1830'), ('name', 'owner of'), ('obj', 'http://www.wikidata.org/entity/Q7357835'), ('objname', 'Roger Bannister running track')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('name', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q1376987'), ('objname', 'New College')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('name', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q2537765'), ('objname', 'Wadham College')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('name', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q745967'), ('objname', 'Christ Church')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('name', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q875538'), ('objname', 'public university')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('name', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q951946'), ('objname', 'Lady Margaret Hall')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('name', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q38723'), ('objname', 'higher education institution')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('name', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q5420001'), ('objname', 'exempt charity')]
# [('p', 'http://www.wikidata.org/prop/direct/P463'), ('name', 'member of'), ('obj', 'http://www.wikidata.org/entity/Q590631'), ('objname', 'Russell Group')]
# [('p', 'http://www.wikidata.org/prop/direct/P463'), ('name', 'member of'), ('obj', 'http://www.wikidata.org/entity/Q6269240'), ('objname', 'Jisc')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('name', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q81092'), ('objname', 'All Souls College')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('name', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q82133'), ('objname', 'Bodleian Library')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('name', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q1819342'), ('objname', "St Anne's College")]
# [('p', 'http://www.wikidata.org/prop/direct/P1416'), ('name', 'affiliation'), ('obj', 'http://www.wikidata.org/entity/Q1140056'), ('objname', 'International Alliance of Research Universities')]
# [('p', 'http://www.wikidata.org/prop/direct/P463'), ('name', 'member of'), ('obj', 'http://www.wikidata.org/entity/Q1140056'), ('objname', 'International Alliance of Research Universities')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('name', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q81087'), ('objname', 'University College, Oxford')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('name', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q2706734'), ('objname', "St Catherine's College")]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('name', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q2706726'), ('objname', 'Harris Manchester College')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('name', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q81173'), ('objname', 'Exeter College')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('name', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q1276338'), ('objname', 'Keble College')]
# [('p', 'http://www.wikidata.org/prop/direct/P355'), ('name', 'subsidiary'), ('obj', 'http://www.wikidata.org/entity/Q30265452'), ('objname', 'Oxford Centre')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('name', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q653483'), ('objname', 'Linacre College')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('name', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q780745'), ('objname', 'Worcester College')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('name', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q81153'), ('objname', 'Lincoln College')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('name', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q899030'), ('objname', 'Brasenose College')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('name', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q2487322'), ('objname', "St Peter's College")]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('name', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q23015771'), ('objname', 'Heather Professor of Music')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('name', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q1738296'), ('objname', 'Kellogg College')]
# [('p', 'http://www.wikidata.org/prop/direct/P417'), ('name', 'patron saint'), ('obj', 'http://www.wikidata.org/entity/Q1314431'), ('objname', 'Frithuswith')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('name', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q2487282'), ('objname', 'Blackfriars')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('name', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q3397198'), ('objname', 'Campion Hall')]
# [('p', 'http://www.wikidata.org/prop/direct/P355'), ('name', 'subsidiary'), ('obj', 'http://www.wikidata.org/entity/Q7370455'), ('objname', 'Rothermere American Institute')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('name', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q2007225'), ('objname', 'Wolfson College')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('name', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q1544655'), ('objname', 'Green Templeton College')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('name', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q2487309'), ('objname', 'Mansfield College')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('name', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q2890677'), ('objname', "St Benet's Hall")]
# [('p', 'http://www.wikidata.org/prop/direct/P355'), ('name', 'subsidiary'), ('obj', 'http://www.wikidata.org/entity/Q7115308'), ('objname', 'Oxford Department of International Development')]
# [('p', 'http://www.wikidata.org/prop/direct/P4195'), ('name', 'category for employees of the organization'), ('obj', 'http://www.wikidata.org/entity/Q7996581'), ('objname', 'Category:Academics of the University of Oxford')]
# [('p', 'http://www.wikidata.org/prop/direct/P1830'), ('name', 'owner of'), ('obj', 'http://www.wikidata.org/entity/Q115451'), ('objname', 'Clarendon Building')]
# [('p', 'http://www.wikidata.org/prop/direct/P355'), ('name', 'subsidiary'), ('obj', 'http://www.wikidata.org/entity/Q45133634'), ('objname', 'Department of Economics, University of Oxford')]
# [('p', 'http://www.wikidata.org/prop/direct/P355'), ('name', 'subsidiary'), ('obj', 'http://www.wikidata.org/entity/Q56815965'), ('objname', 'Nuffield Laboratory of Ophthalmology')]
# [('p', 'http://www.wikidata.org/prop/direct/P355'), ('name', 'subsidiary'), ('obj', 'http://www.wikidata.org/entity/Q21008607'), ('objname', 'Department of Physics, University of Oxford')]
# [('p', 'http://www.wikidata.org/prop/direct/P355'), ('name', 'subsidiary'), ('obj', 'http://www.wikidata.org/entity/Q56612600'), ('objname', 'Nuffield Department of Medicine')]
# [('p', 'http://www.wikidata.org/prop/direct/P1830'), ('name', 'owner of'), ('obj', 'http://www.wikidata.org/entity/Q7280038'), ('objname', 'Radcliffe Science Library')]
# [('p', 'http://www.wikidata.org/prop/direct/P355'), ('name', 'subsidiary'), ('obj', 'http://www.wikidata.org/entity/Q21008611'), ('objname', 'Department of Chemistry, University of Oxford')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('name', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q7308069'), ('objname', "Regent's Park College")]
# [('p', 'http://www.wikidata.org/prop/direct/P361'), ('name', 'part of'), ('obj', 'http://www.wikidata.org/entity/Q642576'), ('objname', 'Oxbridge')]
# [('p', 'http://www.wikidata.org/prop/direct/P1830'), ('name', 'owner of'), ('obj', 'http://www.wikidata.org/entity/Q5419282'), ('objname', 'Examination Schools')]
# [('p', 'http://www.wikidata.org/prop/direct/P355'), ('name', 'subsidiary'), ('obj', 'http://www.wikidata.org/entity/Q5428925'), ('objname', 'Faculty of Classics, University of Oxford')]
# [('p', 'http://www.wikidata.org/prop/direct/P1830'), ('name', 'owner of'), ('obj', 'http://www.wikidata.org/entity/Q83874'), ('objname', 'Sheldonian Theatre')]
# [('p', 'http://www.wikidata.org/prop/direct/P355'), ('name', 'subsidiary'), ('obj', 'http://www.wikidata.org/entity/Q5260200'), ('objname', 'Department of Computer Science, University of Oxford')]
# [('p', 'http://www.wikidata.org/prop/direct/P2354'), ('name', 'has list'), ('obj', 'http://www.wikidata.org/entity/Q6635050'), ('objname', 'list of professorships at the University of Oxford')]
# [('p', 'http://www.wikidata.org/prop/direct/P355'), ('name', 'subsidiary'), ('obj', 'http://www.wikidata.org/entity/Q7761877'), ('objname', 'Ruskin School of Drawing and Fine Art')]
# [('p', 'http://www.wikidata.org/prop/direct/P1830'), ('name', 'owner of'), ('obj', 'http://www.wikidata.org/entity/Q6786826'), ('objname', 'Mathematical Institute, University of Oxford')]
# [('p', 'http://www.wikidata.org/prop/direct/P355'), ('name', 'subsidiary'), ('obj', 'http://www.wikidata.org/entity/Q30265456'), ('objname', 'Oxford Centre for Diabetes, Endocrinology and Metabolism')]
# [('p', 'http://www.wikidata.org/prop/direct/P1830'), ('name', 'owner of'), ('obj', 'http://www.wikidata.org/entity/Q1602700'), ('objname', 'Radcliffe Camera')]
# [('p', 'http://www.wikidata.org/prop/direct/P910'), ('name', "topic's main category"), ('obj', 'http://www.wikidata.org/entity/Q9150156'), ('objname', 'Category:University of Oxford')]
# [('p', 'http://www.wikidata.org/prop/direct/P1424'), ('name', "topic's main template"), ('obj', 'http://www.wikidata.org/entity/Q10970759'), ('objname', 'Template:University of Oxford')]
# [('p', 'http://www.wikidata.org/prop/direct/P355'), ('name', 'subsidiary'), ('obj', 'http://www.wikidata.org/entity/Q7189584'), ('objname', 'Physical and Theoretical Chemistry Laboratory')]
# [('p', 'http://www.wikidata.org/prop/direct/P355'), ('name', 'subsidiary'), ('obj', 'http://www.wikidata.org/entity/Q45132018'), ('objname', 'John Fell Fund, University of Oxford')]
# [('p', 'http://www.wikidata.org/prop/direct/P355'), ('name', 'subsidiary'), ('obj', 'http://www.wikidata.org/entity/Q50975812'), ('objname', 'Institute of Social and Cultural Anthropology')]
# [('p', 'http://www.wikidata.org/prop/direct/P237'), ('name', 'coat of arms'), ('obj', 'http://www.wikidata.org/entity/Q784596'), ('objname', 'Arms of the University of Oxford')]
# 105

# %%
# aim: get all the objects that are instance of 'public university' and 'higher educational institution' containing 'Cambridge' as label
# result: we found a business school that is probably not related to the actual 'University of Cambridge'...
queryString = """
SELECT DISTINCT ?s ?sname
WHERE {
   # bind something
   # ?s wdt:P31 ?obj .
   # get the label
   # ?s sc:name ?sname .
   FILTER (?obj IN (wd:Q875538,wd:Q38723)) .
   
   FILTER regex(?sname, "cambridge", "i")
}
LIMIT 200
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('s', 'http://www.wikidata.org/entity/Q22914845'), ('sname', 'Cambridge Business School in Prague')]
# 1

# %%
# aim: get all the objects related to the location 'Cambridge' by means of opportune regexes
# result: we finally found the 'University of Cambridge'
queryString = """
SELECT DISTINCT ?s ?sname
WHERE {
   # bind something
   # ?s ?p ?obj .
   # get the label
   # ?s sc:name ?sname .
   # ?obj sc:name ?objname
   FILTER (?p IN (wdt:P159,wdt:P276)) .
   FILTER regex(?sname, "university", "i") .
   FILTER regex(?objname, "cambridge", "i") .
}
LIMIT 200
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('s', 'http://www.wikidata.org/entity/Q784593'), ('sname', 'Cambridge University Boat Club')]
# [('s', 'http://www.wikidata.org/entity/Q35794'), ('sname', 'University of Cambridge')]
# [('s', 'http://www.wikidata.org/entity/Q912887'), ('sname', 'Cambridge University Press')]
# [('s', 'http://www.wikidata.org/entity/Q540751'), ('sname', 'Anglia Ruskin University')]
# [('s', 'http://www.wikidata.org/entity/Q100993034'), ('sname', 'Anglia Ruskin University - Cambridge Campus')]
# [('s', 'http://www.wikidata.org/entity/Q100993031'), ('sname', 'Anglia Ruskin University Ashcroft International Business School - Cambridge Campus')]
# [('s', 'http://www.wikidata.org/entity/Q100993035'), ('sname', 'Anglia Ruskin University Department of English Communication Film and Media Cambridge Campus')]
# [('s', 'http://www.wikidata.org/entity/Q101046178'), ('sname', 'University of Cambridge Primary Care Unit')]
# [('s', 'http://www.wikidata.org/entity/Q101010473'), ('sname', 'Anglia Ruskin University Department of Marketing Strategy and Enterprise')]
# [('s', 'http://www.wikidata.org/entity/Q101046169'), ('sname', 'University of Cambridge Centre for Atmospheric Science')]
# [('s', 'http://www.wikidata.org/entity/Q101046172'), ('sname', 'University of Cambridge Clinical Biochemistry')]
# [('s', 'http://www.wikidata.org/entity/Q101046173'), ('sname', 'University of Cambridge Clinical Pharmacology')]
# [('s', 'http://www.wikidata.org/entity/Q101046175'), ('sname', 'University of Cambridge Diagnostics Development Unit')]
# [('s', 'http://www.wikidata.org/entity/Q105169354'), ('sname', 'Cambridge Institute for Medical Research, University of Cambridge')]
# [('s', 'http://www.wikidata.org/entity/Q101010474'), ('sname', 'Anglia Ruskin University Department of Psychology')]
# [('s', 'http://www.wikidata.org/entity/Q101010475'), ('sname', 'Anglia Ruskin University Department of Vision and Hearing Sciences')]
# [('s', 'http://www.wikidata.org/entity/Q101010476'), ('sname', 'University of Cambridge Department of Medical Genetics')]
# [('s', 'http://www.wikidata.org/entity/Q101046170'), ('sname', 'University of Cambridge Centre for Health Leadership and Enterprise')]
# [('s', 'http://www.wikidata.org/entity/Q101046179'), ('sname', 'University of Cambridge Skilliter Centre for Ottoman Studies')]
# [('s', 'http://www.wikidata.org/entity/Q99433423'), ('sname', 'Cambridge University Press Bookshop')]
# [('s', 'http://www.wikidata.org/entity/Q102522142'), ('sname', 'Anglia Ruskin University Cambridge School of Art')]
# [('s', 'http://www.wikidata.org/entity/Q101010471'), ('sname', 'Anglia Ruskin University Department of Human Resource Management Organisational Behaviour and Tourism')]
# [('s', 'http://www.wikidata.org/entity/Q101045055'), ('sname', 'Centre for Business Research University of Cambridge')]
# [('s', 'http://www.wikidata.org/entity/Q101046166'), ('sname', 'University of Cambridge Anaesthesia')]
# [('s', 'http://www.wikidata.org/entity/Q101010472'), ('sname', 'Anglia Ruskin University Department of Life Sciences')]
# [('s', 'http://www.wikidata.org/entity/Q101010470'), ('sname', 'Anglia Ruskin University Department of Humanities and Social Sciences')]
# [('s', 'http://www.wikidata.org/entity/Q101046176'), ('sname', 'University of Cambridge PhD Programme in Developmental Mechanisms')]
# [('s', 'http://www.wikidata.org/entity/Q99459042'), ('sname', 'Cambridge University Press Bookshop Learning Centre')]
# [('s', 'http://www.wikidata.org/entity/Q101045534'), ('sname', 'Open University in the East of England')]
# [('s', 'http://www.wikidata.org/entity/Q101046168'), ('sname', 'University of Cambridge Centre for Applied Medical Statistics')]
# [('s', 'http://www.wikidata.org/entity/Q100993038'), ('sname', 'Anglia Ruskin University Faculty of Health Social Care and Education Cambridge Campus')]
# [('s', 'http://www.wikidata.org/entity/Q5025604'), ('sname', 'Cambridge University Moral Sciences Club')]
# [('s', 'http://www.wikidata.org/entity/Q13371'), ('sname', 'Harvard University')]
# [('s', 'http://www.wikidata.org/entity/Q1587900'), ('sname', 'Harvard University Press')]
# [('s', 'http://www.wikidata.org/entity/Q70627785'), ('sname', 'The University Press')]
# [('s', 'http://www.wikidata.org/entity/Q101076884'), ('sname', 'Harvard University Center for the Environment')]
# [('s', 'http://www.wikidata.org/entity/Q101076918'), ('sname', 'Harvard University Institute of Politics')]
# [('s', 'http://www.wikidata.org/entity/Q101076919'), ('sname', 'Harvard University John King Fairbank Center for Chinese Studies')]
# [('s', 'http://www.wikidata.org/entity/Q101015833'), ('sname', 'Harvard University Department of Chemistry and Chemical Biology')]
# [('s', 'http://www.wikidata.org/entity/Q101015834'), ('sname', 'Harvard University Department of Comparative Literature')]
# [('s', 'http://www.wikidata.org/entity/Q101015837'), ('sname', 'Harvard University Department of English')]
# [('s', 'http://www.wikidata.org/entity/Q101015838'), ('sname', 'Harvard University Department of Environmental Health and Safety')]
# [('s', 'http://www.wikidata.org/entity/Q101015840'), ('sname', 'Harvard University Department of Government')]
# [('s', 'http://www.wikidata.org/entity/Q101015844'), ('sname', 'Harvard University Department of Molecular and Cellular Biology')]
# [('s', 'http://www.wikidata.org/entity/Q101015858'), ('sname', 'Lesley University College of Liberal Arts and Sciences')]
# [('s', 'http://www.wikidata.org/entity/Q101015846'), ('sname', 'Harvard University Department of Music')]
# [('s', 'http://www.wikidata.org/entity/Q101015848'), ('sname', 'Harvard University Department of Physics')]
# [('s', 'http://www.wikidata.org/entity/Q101015849'), ('sname', 'Harvard University Department of Psychology')]
# [('s', 'http://www.wikidata.org/entity/Q101076753'), ('sname', 'Harvard University Center for Jewish Studies')]
# [('s', 'http://www.wikidata.org/entity/Q101076881'), ('sname', 'Harvard University Center for Nanoscale Systems')]
# [('s', 'http://www.wikidata.org/entity/Q101076906'), ('sname', 'Harvard University David Rockefeller Center for Latin American Studies')]
# [('s', 'http://www.wikidata.org/entity/Q101076913'), ('sname', 'Harvard University Harvard Bridge Program')]
# [('s', 'http://www.wikidata.org/entity/Q101076928'), ('sname', 'Harvard University Program for Health Systems Improvement')]
# [('s', 'http://www.wikidata.org/entity/Q101015830'), ('sname', 'Harvard University Department of Art and Architecture')]
# [('s', 'http://www.wikidata.org/entity/Q101015856'), ('sname', 'Harvard University Department of the Classics')]
# [('s', 'http://www.wikidata.org/entity/Q99473664'), ('sname', 'Lesley University Official Bookstore')]
# [('s', 'http://www.wikidata.org/entity/Q101076887'), ('sname', 'Harvard University Center on the Developing Child')]
# [('s', 'http://www.wikidata.org/entity/Q101076924'), ('sname', 'Harvard University Museum of Comparative Zoology Department of Population Genetics')]
# [('s', 'http://www.wikidata.org/entity/Q101076931'), ('sname', 'Harvard University Project on Managing the Atom')]
# [('s', 'http://www.wikidata.org/entity/Q101076932'), ('sname', 'Harvard University Roy and Lila Ash Center for Democratic Governance and Innovation')]
# [('s', 'http://www.wikidata.org/entity/Q101015829'), ('sname', 'Harvard University Department of Anthropology')]
# [('s', 'http://www.wikidata.org/entity/Q101015839'), ('sname', 'Harvard University Department of Germanic Languages and Literatures')]
# [('s', 'http://www.wikidata.org/entity/Q101015847'), ('sname', 'Harvard University Department of Organismic and Evolutionary Biology')]
# [('s', 'http://www.wikidata.org/entity/Q101015852'), ('sname', 'Harvard University Department of Sociology')]
# [('s', 'http://www.wikidata.org/entity/Q101015857'), ('sname', 'Harvard University Department of Visual and Environmental Studies')]
# [('s', 'http://www.wikidata.org/entity/Q101076914'), ('sname', 'Harvard University Institute for Quantitative Social Science')]
# [('s', 'http://www.wikidata.org/entity/Q101015835'), ('sname', 'Harvard University Department of Economics')]
# [('s', 'http://www.wikidata.org/entity/Q101015841'), ('sname', 'Harvard University Department of Landscape Architecture')]
# [('s', 'http://www.wikidata.org/entity/Q101076908'), ('sname', 'Harvard University Division of Continuing Education')]
# [('s', 'http://www.wikidata.org/entity/Q101076923'), ('sname', 'Harvard University Museum of Comparative Zoology Department of Herpetology')]
# [('s', 'http://www.wikidata.org/entity/Q101076747'), ('sname', 'Harvard University Center for Brain Science')]
# [('s', 'http://www.wikidata.org/entity/Q101015851'), ('sname', 'Harvard University Department of Romance Languages and Literatures')]
# [('s', 'http://www.wikidata.org/entity/Q101015853'), ('sname', 'Harvard University Department of Statistics')]
# [('s', 'http://www.wikidata.org/entity/Q101076741'), ('sname', 'Harvard University Asia Center')]
# [('s', 'http://www.wikidata.org/entity/Q101076743'), ('sname', 'Harvard University Belfer Center for Science and International Affairs')]
# [('s', 'http://www.wikidata.org/entity/Q101076745'), ('sname', 'Harvard University Carr Center for Human Rights Policy')]
# [('s', 'http://www.wikidata.org/entity/Q101076876'), ('sname', 'Harvard University Center for Middle Eastern Studies')]
# [('s', 'http://www.wikidata.org/entity/Q101076922'), ('sname', 'Harvard University Minda de Gunzburg Center for European Studies')]
# [('s', 'http://www.wikidata.org/entity/Q101076904'), ('sname', 'Harvard University Charles Warren Center for Studies in American History')]
# [('s', 'http://www.wikidata.org/entity/Q101076920'), ('sname', 'Harvard University Joint Center for Housing Studies')]
# [('s', 'http://www.wikidata.org/entity/Q101015842'), ('sname', 'Harvard University Department of Mathematics')]
# [('s', 'http://www.wikidata.org/entity/Q26391260'), ('sname', 'University Pitt Club')]
# [('s', 'http://www.wikidata.org/entity/Q86020352'), ('sname', 'University of Cambridge Medicine')]
# [('s', 'http://www.wikidata.org/entity/Q28549697'), ('sname', 'Department of Plant Sciences, University of Cambridge')]
# [('s', 'http://www.wikidata.org/entity/Q86020316'), ('sname', 'University of Cambridge Clinical Neurosciences')]
# [('s', 'http://www.wikidata.org/entity/Q86020318'), ('sname', 'University of Cambridge Department of East Asian Studies')]
# [('s', 'http://www.wikidata.org/entity/Q86020354'), ('sname', 'University of Cambridge Neurology Unit')]
# [('s', 'http://www.wikidata.org/entity/Q86026966'), ('sname', 'University of Cambridge Department of Pure Mathematics and Mathematical Statistics')]
# [('s', 'http://www.wikidata.org/entity/Q86026967'), ('sname', 'University of Cambridge Engineering Design Centre')]
# [('s', 'http://www.wikidata.org/entity/Q86026969'), ('sname', 'University of Cambridge Haematology')]
# [('s', 'http://www.wikidata.org/entity/Q86026974'), ('sname', 'University of Cambridge Microelectronics Research Centre')]
# [('s', 'http://www.wikidata.org/entity/Q86026976'), ('sname', 'University of Cambridge Mongolian and Inner Asian Studies Unit')]
# [('s', 'http://www.wikidata.org/entity/Q85960652'), ('sname', 'University of Cambridge Centre for Family Research')]
# [('s', 'http://www.wikidata.org/entity/Q85960656'), ('sname', 'University of Cambridge Wolfson Brain Imaging Centre')]
# [('s', 'http://www.wikidata.org/entity/Q85960858'), ('sname', 'University of Cambridge Centre of South Asian Studies')]
# [('s', 'http://www.wikidata.org/entity/Q85985381'), ('sname', 'University of Cambridge Institute of Public Health')]
# [('s', 'http://www.wikidata.org/entity/Q7894708'), ('sname', 'University Ground, Barnwell')]
# [('s', 'http://www.wikidata.org/entity/Q86020327'), ('sname', 'University of Cambridge Department of History of Art')]
# [('s', 'http://www.wikidata.org/entity/Q86020357'), ('sname', 'University of Cambridge Neurosurgery')]
# [('s', 'http://www.wikidata.org/entity/Q86020366'), ('sname', 'University of Cambridge School of Technology')]
# [('s', 'http://www.wikidata.org/entity/Q86020368'), ('sname', 'University of Cambridge School of the Physical Sciences')]
# [('s', 'http://www.wikidata.org/entity/Q86020369'), ('sname', 'University of Cambridge Surgery')]
# [('s', 'http://www.wikidata.org/entity/Q86021491'), ('sname', 'University of Cambridge Department of Land Economy')]
# [('s', 'http://www.wikidata.org/entity/Q86026978'), ('sname', 'University of Cambridge Transfusion Medicine')]
# [('s', 'http://www.wikidata.org/entity/Q86020334'), ('sname', 'University of Cambridge Department of Pathology')]
# [('s', 'http://www.wikidata.org/entity/Q86020878'), ('sname', 'University of Cambridge Department of Public Health and Primary Care')]
# [('s', 'http://www.wikidata.org/entity/Q85960738'), ('sname', 'University of Cambridge Centre for Intellectual Property and Information Law')]
# [('s', 'http://www.wikidata.org/entity/Q85960823'), ('sname', 'University of Cambridge Language Centre')]
# [('s', 'http://www.wikidata.org/entity/Q86020362'), ('sname', 'University of Cambridge Radiology')]
# [('s', 'http://www.wikidata.org/entity/Q86020337'), ('sname', 'University of Cambridge Department of Slavonic Studies')]
# [('s', 'http://www.wikidata.org/entity/Q86020359'), ('sname', 'University of Cambridge Obstetrics and Gynaecology')]
# [('s', 'http://www.wikidata.org/entity/Q86020360'), ('sname', 'University of Cambridge Orthopaedic Research')]
# [('s', 'http://www.wikidata.org/entity/Q86020759'), ('sname', 'University of Cambridge School of the Humanities and Social Sciences')]
# [('s', 'http://www.wikidata.org/entity/Q86021260'), ('sname', 'University of Cambridge Department of Anglo-Saxon Norse and Celtic')]
# [('s', 'http://www.wikidata.org/entity/Q85960654'), ('sname', 'University of Cambridge Centre of African Studies')]
# [('s', 'http://www.wikidata.org/entity/Q85960650'), ('sname', 'University of Cambridge Cambridge Centre for Brain Repair')]
# [('s', 'http://www.wikidata.org/entity/Q86005308'), ('sname', 'University of Cambridge Faculty of Modern and Medieval Languages')]
# [('s', 'http://www.wikidata.org/entity/Q86020321'), ('sname', 'University of Cambridge Department of German and Dutch')]
# [('s', 'http://www.wikidata.org/entity/Q86020371'), ('sname', 'University of Cambridge Downing College')]
# [('s', 'http://www.wikidata.org/entity/Q86020896'), ('sname', 'University of Cambridge Department of Italian')]
# [('s', 'http://www.wikidata.org/entity/Q86026964'), ('sname', 'University of Cambridge Brain Mapping Unit')]
# [('s', 'http://www.wikidata.org/entity/Q86020347'), ('sname', 'University of Cambridge Developmental Psychiatry')]
# [('s', 'http://www.wikidata.org/entity/Q17021142'), ('sname', 'University of Cambridge Sports Centre')]
# [('s', 'http://www.wikidata.org/entity/Q86005293'), ('sname', 'University of Cambridge Faculty of Architecture and History of Art')]
# [('s', 'http://www.wikidata.org/entity/Q86005313'), ('sname', 'University of Cambridge Faculty of Physics and Chemistry')]
# [('s', 'http://www.wikidata.org/entity/Q86020331'), ('sname', 'University of Cambridge Department of Paediatrics')]
# [('s', 'http://www.wikidata.org/entity/Q86020339'), ('sname', 'University of Cambridge Department of Social Anthropology')]
# [('s', 'http://www.wikidata.org/entity/Q86020341'), ('sname', 'University of Cambridge Department of Sociology')]
# [('s', 'http://www.wikidata.org/entity/Q86020349'), ('sname', 'University of Cambridge Division of Archaeology')]
# [('s', 'http://www.wikidata.org/entity/Q86020818'), ('sname', 'University of Cambridge Division of Biological Anthropology')]
# [('s', 'http://www.wikidata.org/entity/Q86026980'), ('sname', "University of Cambridge Saint Edmund's College")]
# [('s', 'http://www.wikidata.org/entity/Q86003203'), ('sname', 'University of Cambridge Behavioural and Clinical Neuroscience Institute')]
# [('s', 'http://www.wikidata.org/entity/Q86005316'), ('sname', 'University of Cambridge Faculty of Veterinary Medicine')]
# [('s', 'http://www.wikidata.org/entity/Q86015345'), ('sname', 'University of Cambridge Faculty of Economics')]
# [('s', 'http://www.wikidata.org/entity/Q86020329'), ('sname', 'University of Cambridge Department of Middle Eastern Studies')]
# [('s', 'http://www.wikidata.org/entity/Q86005297'), ('sname', 'University of Cambridge Faculty of Biology')]
# [('s', 'http://www.wikidata.org/entity/Q86020320'), ('sname', 'University of Cambridge Department of French')]
# [('s', 'http://www.wikidata.org/entity/Q86020335'), ('sname', 'University of Cambridge Department of Pharmacology')]
# [('s', 'http://www.wikidata.org/entity/Q86020363'), ('sname', 'University of Cambridge School of Arts and Humanities')]
# [('s', 'http://www.wikidata.org/entity/Q86020601'), ('sname', 'University of Cambridge Department of Theoretical and Applied Linguistics')]
# [('s', 'http://www.wikidata.org/entity/Q86021370'), ('sname', 'University of Cambridge Clinical Gerontology')]
# [('s', 'http://www.wikidata.org/entity/Q86027070'), ('sname', 'University of Cambridge Department of Archaeology and Anthropology')]
# [('s', 'http://www.wikidata.org/entity/Q54909497'), ('sname', 'Eur.Th.Group Of Cambridge University')]
# [('s', 'http://www.wikidata.org/entity/Q28970533'), ('sname', 'University of Cambridge Primary School')]
# [('s', 'http://www.wikidata.org/entity/Q86020342'), ('sname', 'University of Cambridge Department of Spanish and Portuguese')]
# [('s', 'http://www.wikidata.org/entity/Q86021258'), ('sname', 'Anglia Ruskin University International English Language Testing System')]
# [('s', 'http://www.wikidata.org/entity/Q86005301'), ('sname', 'University of Cambridge Faculty of Earth Sciences and Geography')]
# [('s', 'http://www.wikidata.org/entity/Q86005302'), ('sname', 'University of Cambridge Faculty of English')]
# [('s', 'http://www.wikidata.org/entity/Q99441452'), ('sname', 'University of Cambridge application to the AHRC Creative Economy Engagement Fellowships scheme')]
# [('s', 'http://www.wikidata.org/entity/Q3731149'), ('sname', 'Harvard University Herbaria')]
# [('s', 'http://www.wikidata.org/entity/Q97070573'), ('sname', 'Harvard University Department of Philosophy')]
# 151

# %%
# aim: get all the properties related to the 'University of Cambridge'
# result: we just found a 'has list' property that might contain a list of students/professors
queryString = """
SELECT DISTINCT ?p ?name
WHERE {
   # bind something
   wd:Q35794 ?p ?obj .
   # get the label
   # ?p sc:name ?name .
}
LIMIT 200
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P6733'), ('name', 'National Taxonomy of Exempt Entities code')]
# [('p', 'http://www.wikidata.org/prop/direct/P1004'), ('name', 'MusicBrainz place ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1005'), ('name', 'Portuguese National Library ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1017'), ('name', 'Vatican Library ID (former scheme)')]
# [('p', 'http://www.wikidata.org/prop/direct/P1296'), ('name', 'Gran Enciclopèdia Catalana ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P131'), ('name', 'located in the administrative territorial entity')]
# [('p', 'http://www.wikidata.org/prop/direct/P1329'), ('name', 'phone number')]
# [('p', 'http://www.wikidata.org/prop/direct/P1343'), ('name', 'described by source')]
# [('p', 'http://www.wikidata.org/prop/direct/P1416'), ('name', 'affiliation')]
# [('p', 'http://www.wikidata.org/prop/direct/P1417'), ('name', 'Encyclopædia Britannica Online ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1448'), ('name', 'official name')]
# [('p', 'http://www.wikidata.org/prop/direct/P154'), ('name', 'logo image')]
# [('p', 'http://www.wikidata.org/prop/direct/P1566'), ('name', 'GeoNames ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P159'), ('name', 'headquarters location')]
# [('p', 'http://www.wikidata.org/prop/direct/P1612'), ('name', 'Commons Institution page')]
# [('p', 'http://www.wikidata.org/prop/direct/P1617'), ('name', 'BBC Things ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P17'), ('name', 'country')]
# [('p', 'http://www.wikidata.org/prop/direct/P1705'), ('name', 'native label')]
# [('p', 'http://www.wikidata.org/prop/direct/P1711'), ('name', 'British Museum person or institution ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P18'), ('name', 'image')]
# [('p', 'http://www.wikidata.org/prop/direct/P1830'), ('name', 'owner of')]
# [('p', 'http://www.wikidata.org/prop/direct/P2002'), ('name', 'Twitter username')]
# [('p', 'http://www.wikidata.org/prop/direct/P2003'), ('name', 'Instagram username')]
# [('p', 'http://www.wikidata.org/prop/direct/P2013'), ('name', 'Facebook ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2088'), ('name', 'Crunchbase organization ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P213'), ('name', 'ISNI')]
# [('p', 'http://www.wikidata.org/prop/direct/P214'), ('name', 'VIAF ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2163'), ('name', 'FAST ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2196'), ('name', 'students count')]
# [('p', 'http://www.wikidata.org/prop/direct/P227'), ('name', 'GND ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2354'), ('name', 'has list')]
# [('p', 'http://www.wikidata.org/prop/direct/P237'), ('name', 'coat of arms')]
# [('p', 'http://www.wikidata.org/prop/direct/P2427'), ('name', 'GRID ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P244'), ('name', 'Library of Congress authority ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P245'), ('name', 'Union List of Artist Names ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2468'), ('name', 'Theatricalia theatre ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2581'), ('name', 'BabelNet ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P268'), ('name', 'Bibliothèque nationale de France ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P269'), ('name', 'IdRef ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P276'), ('name', 'location')]
# [('p', 'http://www.wikidata.org/prop/direct/P281'), ('name', 'postal code')]
# [('p', 'http://www.wikidata.org/prop/direct/P2959'), ('name', 'permanent duplicated item')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('name', 'instance of')]
# [('p', 'http://www.wikidata.org/prop/direct/P3153'), ('name', 'Crossref funder ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3219'), ('name', 'Encyclopædia Universalis ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3221'), ('name', 'New York Times topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3222'), ('name', 'NE.se ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3267'), ('name', 'Flickr user ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3348'), ('name', 'National Library of Greece ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3393'), ('name', 'LittleSis organization ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3417'), ('name', 'Quora topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3500'), ('name', 'Ringgold ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P355'), ('name', 'subsidiary')]
# [('p', 'http://www.wikidata.org/prop/direct/P3553'), ('name', 'Zhihu topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3608'), ('name', 'EU VAT number')]
# [('p', 'http://www.wikidata.org/prop/direct/P361'), ('name', 'part of')]
# [('p', 'http://www.wikidata.org/prop/direct/P373'), ('name', 'Commons category')]
# [('p', 'http://www.wikidata.org/prop/direct/P3749'), ('name', 'Google Maps Customer ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3761'), ('name', 'IPv4 routing prefix')]
# [('p', 'http://www.wikidata.org/prop/direct/P3762'), ('name', 'openMLOL author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3793'), ('name', 'IPv6 routing prefix')]
# [('p', 'http://www.wikidata.org/prop/direct/P3876'), ('name', 'category for alumni of educational institution')]
# [('p', 'http://www.wikidata.org/prop/direct/P3987'), ('name', 'SHARE Catalogue author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P4081'), ('name', 'BHL creator ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P409'), ('name', 'Libraries Australia ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P4195'), ('name', 'category for employees of the organization')]
# [('p', 'http://www.wikidata.org/prop/direct/P4389'), ('name', 'Science Museum people ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P4527'), ('name', 'UK Parliament thesaurus ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P463'), ('name', 'member of')]
# [('p', 'http://www.wikidata.org/prop/direct/P4672'), ('name', 'EMLO location ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5063'), ('name', 'Interlingual Index ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5242'), ('name', 'ARWU university ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('name', 'has part')]
# [('p', 'http://www.wikidata.org/prop/direct/P5361'), ('name', 'BNB person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5584'), ('name', 'QS World University ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5586'), ('name', 'Times Higher Education World University ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5600'), ('name', 'U-Multirank university ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P571'), ('name', 'inception')]
# [('p', 'http://www.wikidata.org/prop/direct/P5785'), ('name', 'EU Research participant ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5905'), ('name', 'Comic Vine ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6200'), ('name', 'BBC News topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6269'), ('name', 'API endpoint')]
# [('p', 'http://www.wikidata.org/prop/direct/P6366'), ('name', 'Microsoft Academic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P646'), ('name', 'Freebase ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6683'), ('name', 'Alexander Turnbull Library ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6698'), ('name', 'Japan Search name ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6782'), ('name', 'ROR ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P691'), ('name', 'NKCR AUT ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7305'), ('name', 'Online PWN Encyclopedia ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7400'), ('name', 'LibraryThing author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7502'), ('name', 'Golden ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7859'), ('name', 'WorldCat Identities ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7959'), ('name', 'historic county')]
# [('p', 'http://www.wikidata.org/prop/direct/P7982'), ('name', 'Hrvatska enciklopedija ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8034'), ('name', 'Vatican Library VcBA ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8168'), ('name', 'FactGrid item ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8408'), ('name', 'KBpedia ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P856'), ('name', 'official website')]
# [('p', 'http://www.wikidata.org/prop/direct/P8687'), ('name', 'social media followers')]
# [('p', 'http://www.wikidata.org/prop/direct/P8826'), ('name', 'edition humboldt digital ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P910'), ('name', "topic's main category")]
# [('p', 'http://www.wikidata.org/prop/direct/P9100'), ('name', 'GitHub topic')]
# [('p', 'http://www.wikidata.org/prop/direct/P9226'), ('name', 'ARAE ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P9287'), ('name', 'Cyprus Bibliography ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P935'), ('name', 'Commons gallery')]
# [('p', 'http://www.wikidata.org/prop/direct/P94'), ('name', 'coat of arms image')]
# [('p', 'http://www.wikidata.org/prop/direct/P949'), ('name', 'National Library of Israel ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P950'), ('name', 'Biblioteca Nacional de España ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P9545'), ('name', 'Encyclopedia of China Online Database ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P9756'), ('name', 'Schoenberg Database of Manuscripts name ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3899'), ('name', 'Medium username')]
# [('p', 'http://www.wikidata.org/prop/direct/P1297'), ('name', 'IRS Employer Identification Number')]
# [('p', 'http://www.wikidata.org/prop/direct/P3642'), ('name', 'ARCHON code')]
# [('p', 'http://www.wikidata.org/prop/direct/P1602'), ('name', 'Art UK venue ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2253'), ('name', 'DfE URN')]
# [('p', 'http://www.wikidata.org/prop/direct/P4971'), ('name', 'UK Provider Reference Number')]
# [('p', 'http://www.wikidata.org/prop/direct/P2740'), ('name', 'ResearchGate institute ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5894'), ('name', 'tuition fee')]
# 118

# %%
# aim: get the objects of 'has list'
# result: we found a object that might be perfect for the final query!
queryString = """
SELECT DISTINCT ?obj ?name
WHERE {
   # bind something
   wd:Q35794 wdt:P2354 ?obj .
   # get the label
   # ?obj sc:name ?name .
}
LIMIT 200
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('obj', 'http://www.wikidata.org/entity/Q6635048'), ('name', 'list of professorships at the University of Cambridge')]
# 1

# %%
# aim: get all the objects and properties related to 'list of professorships at the University of Cambridge'
# result: we didn't find the actual list of professors 
queryString = """
SELECT DISTINCT ?p ?pname ?obj ?name
WHERE {
   # bind something
   wd:Q6635048 ?p ?obj .
   # get the label
   # ?p sc:name ?pname .
   # ?obj sc:name ?name .
}
LIMIT 200
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pname', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q13406463'), ('name', 'Wikimedia list article')]
# [('p', 'http://www.wikidata.org/prop/direct/P360'), ('pname', 'is a list of'), ('obj', 'http://www.wikidata.org/entity/Q1363750'), ('name', 'chair')]
# [('p', 'http://www.wikidata.org/prop/direct/P360'), ('pname', 'is a list of'), ('obj', 'http://www.wikidata.org/entity/Q81752537'), ('name', 'professorship')]
# [('p', 'http://www.wikidata.org/prop/direct/P360'), ('pname', 'is a list of'), ('obj', 'http://www.wikidata.org/entity/Q2138652'), ('name', 'Regius Professor')]
# [('p', 'http://www.wikidata.org/prop/direct/P1754'), ('pname', 'category related to list'), ('obj', 'http://www.wikidata.org/entity/Q7018986'), ('name', 'Category:Professorships at the University of Cambridge')]
# 5

# %%
# aim: get all the properties related to 'list of professorships at the University of Cambridge'
# result: we didn't find the actual list of professors but maybe we need to explore the 'Category:Professorships at the University of Cambridge' object
queryString = """
SELECT DISTINCT ?p ?pname
WHERE {
   # bind something
   # ?s ?p  wd:Q6635048 .
   # get the label
   # ?p sc:name ?pname .
}
LIMIT 200
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P1753'), ('pname', 'list related to category')]
# [('p', 'http://www.wikidata.org/prop/direct/P2354'), ('pname', 'has list')]
# 2

# %%
# aim: get all the objects and properties related to 'Category:Professorships at the University of Cambridge'
# result: we didn't find anything, we are looping...
queryString = """
SELECT DISTINCT ?p ?pname ?obj ?name
WHERE {
   # bind something
   wd:Q7018986 ?p ?obj .
   # get the label
   # ?p sc:name ?pname .
   # ?obj sc:name ?name .
}
LIMIT 200
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P971'), ('pname', 'category combines topics'), ('obj', 'http://www.wikidata.org/entity/Q35794'), ('name', 'University of Cambridge')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pname', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q4167836'), ('name', 'Wikimedia category')]
# [('p', 'http://www.wikidata.org/prop/direct/P971'), ('pname', 'category combines topics'), ('obj', 'http://www.wikidata.org/entity/Q81752537'), ('name', 'professorship')]
# [('p', 'http://www.wikidata.org/prop/direct/P4224'), ('pname', 'category contains'), ('obj', 'http://www.wikidata.org/entity/Q81752537'), ('name', 'professorship')]
# [('p', 'http://www.wikidata.org/prop/direct/P1753'), ('pname', 'list related to category'), ('obj', 'http://www.wikidata.org/entity/Q6635048'), ('name', 'list of professorships at the University of Cambridge')]
# 5

# %%
# aim: get all the properties in relation with the 'University of Cambridge'
# result: we just found some properties related to possible workers at the university
queryString = """
SELECT DISTINCT ?p ?name
WHERE {
   # bind something
   # ?s ?p wd:Q35794 .
   # get the label
   # ?p sc:name ?name .
}
LIMIT 200
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P2389'), ('name', 'organization directed by the office or position')]
# [('p', 'http://www.wikidata.org/prop/direct/P108'), ('name', 'employer')]
# [('p', 'http://www.wikidata.org/prop/direct/P123'), ('name', 'publisher')]
# [('p', 'http://www.wikidata.org/prop/direct/P1269'), ('name', 'facet of')]
# [('p', 'http://www.wikidata.org/prop/direct/P127'), ('name', 'owned by')]
# [('p', 'http://www.wikidata.org/prop/direct/P137'), ('name', 'operator')]
# [('p', 'http://www.wikidata.org/prop/direct/P138'), ('name', 'named after')]
# [('p', 'http://www.wikidata.org/prop/direct/P1416'), ('name', 'affiliation')]
# [('p', 'http://www.wikidata.org/prop/direct/P159'), ('name', 'headquarters location')]
# [('p', 'http://www.wikidata.org/prop/direct/P178'), ('name', 'developer')]
# [('p', 'http://www.wikidata.org/prop/direct/P20'), ('name', 'place of death')]
# [('p', 'http://www.wikidata.org/prop/direct/P2541'), ('name', 'operating area')]
# [('p', 'http://www.wikidata.org/prop/direct/P276'), ('name', 'location')]
# [('p', 'http://www.wikidata.org/prop/direct/P291'), ('name', 'place of publication')]
# [('p', 'http://www.wikidata.org/prop/direct/P2959'), ('name', 'permanent duplicated item')]
# [('p', 'http://www.wikidata.org/prop/direct/P301'), ('name', "category's main topic")]
# [('p', 'http://www.wikidata.org/prop/direct/P361'), ('name', 'part of')]
# [('p', 'http://www.wikidata.org/prop/direct/P463'), ('name', 'member of')]
# [('p', 'http://www.wikidata.org/prop/direct/P485'), ('name', 'archives at')]
# [('p', 'http://www.wikidata.org/prop/direct/P50'), ('name', 'author')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('name', 'has part')]
# [('p', 'http://www.wikidata.org/prop/direct/P61'), ('name', 'discoverer or inventor')]
# [('p', 'http://www.wikidata.org/prop/direct/P6379'), ('name', 'has works in the collection')]
# [('p', 'http://www.wikidata.org/prop/direct/P65'), ('name', 'site of astronomical discovery')]
# [('p', 'http://www.wikidata.org/prop/direct/P664'), ('name', 'organizer')]
# [('p', 'http://www.wikidata.org/prop/direct/P69'), ('name', 'educated at')]
# [('p', 'http://www.wikidata.org/prop/direct/P710'), ('name', 'participant')]
# [('p', 'http://www.wikidata.org/prop/direct/P749'), ('name', 'parent organization')]
# [('p', 'http://www.wikidata.org/prop/direct/P797'), ('name', 'authority')]
# [('p', 'http://www.wikidata.org/prop/direct/P803'), ('name', 'professorship')]
# [('p', 'http://www.wikidata.org/prop/direct/P859'), ('name', 'sponsor')]
# [('p', 'http://www.wikidata.org/prop/direct/P915'), ('name', 'filming location')]
# [('p', 'http://www.wikidata.org/prop/direct/P921'), ('name', 'main subject')]
# [('p', 'http://www.wikidata.org/prop/direct/P937'), ('name', 'work location')]
# [('p', 'http://www.wikidata.org/prop/direct/P971'), ('name', 'category combines topics')]
# [('p', 'http://www.wikidata.org/prop/direct/P98'), ('name', 'editor')]
# [('p', 'http://www.wikidata.org/prop/direct/P1433'), ('name', 'published in')]
# [('p', 'http://www.wikidata.org/prop/direct/P1027'), ('name', 'conferred by')]
# [('p', 'http://www.wikidata.org/prop/direct/P1891'), ('name', 'signatory')]
# [('p', 'http://www.wikidata.org/prop/direct/P248'), ('name', 'stated in')]
# [('p', 'http://www.wikidata.org/prop/direct/P2652'), ('name', 'partnership with')]
# [('p', 'http://www.wikidata.org/prop/direct/P6153'), ('name', 'research site')]
# [('p', 'http://www.wikidata.org/prop/direct/P4101'), ('name', 'dissertation submitted to')]
# [('p', 'http://www.wikidata.org/prop/direct/P1855'), ('name', 'Wikidata property example')]
# 44

# %%
# aim: explore the objects with properties 'employer', 'professorship', 'work location' and 'member of' in relation with 'University of Cambridge'
# result: there are for sure many 'employer's. We check each property separately
queryString = """
SELECT DISTINCT ?p ?pname ?s ?name
WHERE {
   # bind something
   # ?s ?p wd:Q35794 .
   # get the label
   # ?p sc:name ?pname .
   # ?s sc:name ?name .
   FILTER (?p IN (wdt:P463,wdt:P108,wdt:P937,wdt:P803))
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P108'), ('pname', 'employer'), ('s', 'http://www.wikidata.org/entity/Q17022827'), ('name', 'Ashok Venkitaraman')]
# [('p', 'http://www.wikidata.org/prop/direct/P108'), ('pname', 'employer'), ('s', 'http://www.wikidata.org/entity/Q8990547'), ('name', 'Liu Yu')]
# [('p', 'http://www.wikidata.org/prop/direct/P108'), ('pname', 'employer'), ('s', 'http://www.wikidata.org/entity/Q19335551'), ('name', 'Mildred Blaxter')]
# [('p', 'http://www.wikidata.org/prop/direct/P108'), ('pname', 'employer'), ('s', 'http://www.wikidata.org/entity/Q21613245'), ('name', 'Richard Henry Yapp')]
# [('p', 'http://www.wikidata.org/prop/direct/P108'), ('pname', 'employer'), ('s', 'http://www.wikidata.org/entity/Q29654050'), ('name', 'Duncan Odom')]
# [('p', 'http://www.wikidata.org/prop/direct/P108'), ('pname', 'employer'), ('s', 'http://www.wikidata.org/entity/Q44172566'), ('name', 'Sharon Peacock')]
# [('p', 'http://www.wikidata.org/prop/direct/P108'), ('pname', 'employer'), ('s', 'http://www.wikidata.org/entity/Q5201079'), ('name', 'Cyrus Chothia')]
# [('p', 'http://www.wikidata.org/prop/direct/P108'), ('pname', 'employer'), ('s', 'http://www.wikidata.org/entity/Q55302620'), ('name', 'Claudia Kutter')]
# [('p', 'http://www.wikidata.org/prop/direct/P108'), ('pname', 'employer'), ('s', 'http://www.wikidata.org/entity/Q29642394'), ('name', 'Carol Brayne')]
# [('p', 'http://www.wikidata.org/prop/direct/P108'), ('pname', 'employer'), ('s', 'http://www.wikidata.org/entity/Q4859279'), ('name', 'Barbara J. Sahakian')]
# [('p', 'http://www.wikidata.org/prop/direct/P108'), ('pname', 'employer'), ('s', 'http://www.wikidata.org/entity/Q50286338'), ('name', 'Sally J Wheelwright')]
# [('p', 'http://www.wikidata.org/prop/direct/P108'), ('pname', 'employer'), ('s', 'http://www.wikidata.org/entity/Q5512216'), ('name', 'Germán Elías Berríos')]
# [('p', 'http://www.wikidata.org/prop/direct/P108'), ('pname', 'employer'), ('s', 'http://www.wikidata.org/entity/Q7177066'), ('name', 'Peter Henry St George-Hyslop')]
# [('p', 'http://www.wikidata.org/prop/direct/P108'), ('pname', 'employer'), ('s', 'http://www.wikidata.org/entity/Q31095250'), ('name', 'Paul Ramchandani')]
# [('p', 'http://www.wikidata.org/prop/direct/P108'), ('pname', 'employer'), ('s', 'http://www.wikidata.org/entity/Q15994491'), ('name', 'Phillip Thomas Hawkins')]
# [('p', 'http://www.wikidata.org/prop/direct/P108'), ('pname', 'employer'), ('s', 'http://www.wikidata.org/entity/Q15994759'), ('name', 'Maria Grazia Spillantini')]
# [('p', 'http://www.wikidata.org/prop/direct/P108'), ('pname', 'employer'), ('s', 'http://www.wikidata.org/entity/Q15994767'), ('name', 'Leonard R. Stephens')]
# [('p', 'http://www.wikidata.org/prop/direct/P108'), ('pname', 'employer'), ('s', 'http://www.wikidata.org/entity/Q24004353'), ('name', 'Ramanujan Shankar Hegde')]
# [('p', 'http://www.wikidata.org/prop/direct/P108'), ('pname', 'employer'), ('s', 'http://www.wikidata.org/entity/Q37377097'), ('name', 'Charlie E Massie')]
# [('p', 'http://www.wikidata.org/prop/direct/P108'), ('pname', 'employer'), ('s', 'http://www.wikidata.org/entity/Q37379990'), ('name', "Cahir J O'Kane")]
# [('p', 'http://www.wikidata.org/prop/direct/P108'), ('pname', 'employer'), ('s', 'http://www.wikidata.org/entity/Q42645187'), ('name', 'Suet-feung Chin')]
# [('p', 'http://www.wikidata.org/prop/direct/P108'), ('pname', 'employer'), ('s', 'http://www.wikidata.org/entity/Q42664072'), ('name', 'Rory Stark')]
# [('p', 'http://www.wikidata.org/prop/direct/P108'), ('pname', 'employer'), ('s', 'http://www.wikidata.org/entity/Q42943935'), ('name', 'Alexander J. Whitworth')]
# [('p', 'http://www.wikidata.org/prop/direct/P108'), ('pname', 'employer'), ('s', 'http://www.wikidata.org/entity/Q44831886'), ('name', 'Cecile Lebrand')]
# [('p', 'http://www.wikidata.org/prop/direct/P108'), ('pname', 'employer'), ('s', 'http://www.wikidata.org/entity/Q51524557'), ('name', 'Catherine Lindon')]
# [('p', 'http://www.wikidata.org/prop/direct/P108'), ('pname', 'employer'), ('s', 'http://www.wikidata.org/entity/Q55296476'), ('name', 'Manuela Kathrin Hospenthal')]
# [('p', 'http://www.wikidata.org/prop/direct/P108'), ('pname', 'employer'), ('s', 'http://www.wikidata.org/entity/Q56435841'), ('name', 'Eamonn R Maher')]
# [('p', 'http://www.wikidata.org/prop/direct/P108'), ('pname', 'employer'), ('s', 'http://www.wikidata.org/entity/Q56697361'), ('name', 'S Brown')]
# [('p', 'http://www.wikidata.org/prop/direct/P108'), ('pname', 'employer'), ('s', 'http://www.wikidata.org/entity/Q57157274'), ('name', 'Payam A Gammage')]
# [('p', 'http://www.wikidata.org/prop/direct/P108'), ('pname', 'employer'), ('s', 'http://www.wikidata.org/entity/Q57421057'), ('name', 'Laura Tosatto')]
# [('p', 'http://www.wikidata.org/prop/direct/P108'), ('pname', 'employer'), ('s', 'http://www.wikidata.org/entity/Q57515346'), ('name', 'Nicholas Brindle')]
# [('p', 'http://www.wikidata.org/prop/direct/P108'), ('pname', 'employer'), ('s', 'http://www.wikidata.org/entity/Q58336947'), ('name', 'Blerta Xhemalce')]
# [('p', 'http://www.wikidata.org/prop/direct/P108'), ('pname', 'employer'), ('s', 'http://www.wikidata.org/entity/Q38640569'), ('name', 'Victor M Bolanos-Garcia')]
# [('p', 'http://www.wikidata.org/prop/direct/P108'), ('pname', 'employer'), ('s', 'http://www.wikidata.org/entity/Q39886460'), ('name', 'Mei-See Man')]
# [('p', 'http://www.wikidata.org/prop/direct/P108'), ('pname', 'employer'), ('s', 'http://www.wikidata.org/entity/Q42574062'), ('name', 'Lora K Heisler')]
# [('p', 'http://www.wikidata.org/prop/direct/P108'), ('pname', 'employer'), ('s', 'http://www.wikidata.org/entity/Q54760735'), ('name', 'Varodom Charoensawan')]
# [('p', 'http://www.wikidata.org/prop/direct/P108'), ('pname', 'employer'), ('s', 'http://www.wikidata.org/entity/Q1376924'), ('name', 'Frederic William Maitland')]
# [('p', 'http://www.wikidata.org/prop/direct/P108'), ('pname', 'employer'), ('s', 'http://www.wikidata.org/entity/Q41044981'), ('name', 'Carlo Camilloni')]
# [('p', 'http://www.wikidata.org/prop/direct/P108'), ('pname', 'employer'), ('s', 'http://www.wikidata.org/entity/Q311778'), ('name', 'John Dalberg-Acton, 1st Baron Acton')]
# [('p', 'http://www.wikidata.org/prop/direct/P108'), ('pname', 'employer'), ('s', 'http://www.wikidata.org/entity/Q58762171'), ('name', 'Campbell D Lawson')]
# [('p', 'http://www.wikidata.org/prop/direct/P108'), ('pname', 'employer'), ('s', 'http://www.wikidata.org/entity/Q38320743'), ('name', 'Yorgo Modis')]
# [('p', 'http://www.wikidata.org/prop/direct/P108'), ('pname', 'employer'), ('s', 'http://www.wikidata.org/entity/Q30143674'), ('name', 'Charlotte Coles')]
# [('p', 'http://www.wikidata.org/prop/direct/P108'), ('pname', 'employer'), ('s', 'http://www.wikidata.org/entity/Q48078059'), ('name', 'Sebastian Schornack')]
# [('p', 'http://www.wikidata.org/prop/direct/P108'), ('pname', 'employer'), ('s', 'http://www.wikidata.org/entity/Q57467697'), ('name', 'Hajk-Georg Drost')]
# [('p', 'http://www.wikidata.org/prop/direct/P108'), ('pname', 'employer'), ('s', 'http://www.wikidata.org/entity/Q60534237'), ('name', 'James Hook')]
# [('p', 'http://www.wikidata.org/prop/direct/P108'), ('pname', 'employer'), ('s', 'http://www.wikidata.org/entity/Q64667591'), ('name', 'Massimiliano Bonomi')]
# [('p', 'http://www.wikidata.org/prop/direct/P108'), ('pname', 'employer'), ('s', 'http://www.wikidata.org/entity/Q7609121'), ('name', 'Stephen E. Harding')]
# [('p', 'http://www.wikidata.org/prop/direct/P108'), ('pname', 'employer'), ('s', 'http://www.wikidata.org/entity/Q51502301'), ('name', 'Richard Prager')]
# [('p', 'http://www.wikidata.org/prop/direct/P108'), ('pname', 'employer'), ('s', 'http://www.wikidata.org/entity/Q32652665'), ('name', 'Leonardo Bottolo')]
# [('p', 'http://www.wikidata.org/prop/direct/P108'), ('pname', 'employer'), ('s', 'http://www.wikidata.org/entity/Q42762166'), ('name', 'Flemming Hofmann Larsen')]
# [('p', 'http://www.wikidata.org/prop/direct/P108'), ('pname', 'employer'), ('s', 'http://www.wikidata.org/entity/Q54087230'), ('name', 'Jean Sanderson')]
# [('p', 'http://www.wikidata.org/prop/direct/P108'), ('pname', 'employer'), ('s', 'http://www.wikidata.org/entity/Q47815020'), ('name', 'Michael Lee')]
# [('p', 'http://www.wikidata.org/prop/direct/P108'), ('pname', 'employer'), ('s', 'http://www.wikidata.org/entity/Q64021035'), ('name', 'John A. Hertz')]
# [('p', 'http://www.wikidata.org/prop/direct/P108'), ('pname', 'employer'), ('s', 'http://www.wikidata.org/entity/Q89935973'), ('name', 'Li Su')]
# [('p', 'http://www.wikidata.org/prop/direct/P108'), ('pname', 'employer'), ('s', 'http://www.wikidata.org/entity/Q2252186'), ('name', 'John Birks')]
# [('p', 'http://www.wikidata.org/prop/direct/P108'), ('pname', 'employer'), ('s', 'http://www.wikidata.org/entity/Q42835621'), ('name', 'Johan Mölne')]
# [('p', 'http://www.wikidata.org/prop/direct/P108'), ('pname', 'employer'), ('s', 'http://www.wikidata.org/entity/Q47113348'), ('name', 'Michael J Sweeting')]
# [('p', 'http://www.wikidata.org/prop/direct/P108'), ('pname', 'employer'), ('s', 'http://www.wikidata.org/entity/Q51751180'), ('name', 'John Charles Walmsley')]
# [('p', 'http://www.wikidata.org/prop/direct/P108'), ('pname', 'employer'), ('s', 'http://www.wikidata.org/entity/Q55154260'), ('name', 'Richard Williams')]
# [('p', 'http://www.wikidata.org/prop/direct/P108'), ('pname', 'employer'), ('s', 'http://www.wikidata.org/entity/Q30513910'), ('name', 'David W Dunne')]
# [('p', 'http://www.wikidata.org/prop/direct/P108'), ('pname', 'employer'), ('s', 'http://www.wikidata.org/entity/Q38323884'), ('name', 'Brian Hendrich')]
# [('p', 'http://www.wikidata.org/prop/direct/P108'), ('pname', 'employer'), ('s', 'http://www.wikidata.org/entity/Q38547073'), ('name', 'Luke Clark')]
# [('p', 'http://www.wikidata.org/prop/direct/P108'), ('pname', 'employer'), ('s', 'http://www.wikidata.org/entity/Q42944857'), ('name', 'Padraic G. Fallon')]
# [('p', 'http://www.wikidata.org/prop/direct/P108'), ('pname', 'employer'), ('s', 'http://www.wikidata.org/entity/Q54006673'), ('name', 'Shane McCarthy')]
# [('p', 'http://www.wikidata.org/prop/direct/P108'), ('pname', 'employer'), ('s', 'http://www.wikidata.org/entity/Q84508270'), ('name', 'Audrey Hay')]
# [('p', 'http://www.wikidata.org/prop/direct/P108'), ('pname', 'employer'), ('s', 'http://www.wikidata.org/entity/Q57011184'), ('name', 'Rosalind Parkes-Ratanshi')]
# [('p', 'http://www.wikidata.org/prop/direct/P108'), ('pname', 'employer'), ('s', 'http://www.wikidata.org/entity/Q1287932'), ('name', 'Eduard Arzt')]
# [('p', 'http://www.wikidata.org/prop/direct/P108'), ('pname', 'employer'), ('s', 'http://www.wikidata.org/entity/Q30169412'), ('name', 'Erika Fernandez-Vizarra')]
# [('p', 'http://www.wikidata.org/prop/direct/P108'), ('pname', 'employer'), ('s', 'http://www.wikidata.org/entity/Q37618223'), ('name', 'Maanasa Raghavan')]
# [('p', 'http://www.wikidata.org/prop/direct/P108'), ('pname', 'employer'), ('s', 'http://www.wikidata.org/entity/Q38546038'), ('name', 'Matthew Gilliham')]
# [('p', 'http://www.wikidata.org/prop/direct/P108'), ('pname', 'employer'), ('s', 'http://www.wikidata.org/entity/Q41840560'), ('name', 'Anthony C Smith')]
# [('p', 'http://www.wikidata.org/prop/direct/P108'), ('pname', 'employer'), ('s', 'http://www.wikidata.org/entity/Q51815933'), ('name', 'Christian Frezza')]
# [('p', 'http://www.wikidata.org/prop/direct/P108'), ('pname', 'employer'), ('s', 'http://www.wikidata.org/entity/Q57000419'), ('name', 'Sara Wade')]
# [('p', 'http://www.wikidata.org/prop/direct/P108'), ('pname', 'employer'), ('s', 'http://www.wikidata.org/entity/Q57651069'), ('name', 'Amber N V Ruigrok')]
# [('p', 'http://www.wikidata.org/prop/direct/P108'), ('pname', 'employer'), ('s', 'http://www.wikidata.org/entity/Q61090546'), ('name', 'Thomas Krieg')]
# [('p', 'http://www.wikidata.org/prop/direct/P108'), ('pname', 'employer'), ('s', 'http://www.wikidata.org/entity/Q64495833'), ('name', 'Ana S.H. Costa')]
# [('p', 'http://www.wikidata.org/prop/direct/P108'), ('pname', 'employer'), ('s', 'http://www.wikidata.org/entity/Q86166593'), ('name', 'Giulia Biffi')]
# [('p', 'http://www.wikidata.org/prop/direct/P108'), ('pname', 'employer'), ('s', 'http://www.wikidata.org/entity/Q56596752'), ('name', 'Ernest Turro')]
# [('p', 'http://www.wikidata.org/prop/direct/P108'), ('pname', 'employer'), ('s', 'http://www.wikidata.org/entity/Q57419377'), ('name', 'Lu Chen')]
# [('p', 'http://www.wikidata.org/prop/direct/P108'), ('pname', 'employer'), ('s', 'http://www.wikidata.org/entity/Q59222761'), ('name', 'Amy Devine')]
# [('p', 'http://www.wikidata.org/prop/direct/P108'), ('pname', 'employer'), ('s', 'http://www.wikidata.org/entity/Q59540166'), ('name', 'Tiphaine Martin')]
# [('p', 'http://www.wikidata.org/prop/direct/P108'), ('pname', 'employer'), ('s', 'http://www.wikidata.org/entity/Q48555095'), ('name', 'Mike R. Clark')]
# [('p', 'http://www.wikidata.org/prop/direct/P108'), ('pname', 'employer'), ('s', 'http://www.wikidata.org/entity/Q50947555'), ('name', 'Anton Vidal-Ferran')]
# [('p', 'http://www.wikidata.org/prop/direct/P108'), ('pname', 'employer'), ('s', 'http://www.wikidata.org/entity/Q56480701'), ('name', 'David Lando')]
# [('p', 'http://www.wikidata.org/prop/direct/P108'), ('pname', 'employer'), ('s', 'http://www.wikidata.org/entity/Q56843075'), ('name', 'Alexis de Rougemont')]
# [('p', 'http://www.wikidata.org/prop/direct/P108'), ('pname', 'employer'), ('s', 'http://www.wikidata.org/entity/Q61089752'), ('name', 'Florian Marks')]
# [('p', 'http://www.wikidata.org/prop/direct/P108'), ('pname', 'employer'), ('s', 'http://www.wikidata.org/entity/Q21264533'), ('name', 'Rachel Angharad Oliver')]
# [('p', 'http://www.wikidata.org/prop/direct/P108'), ('pname', 'employer'), ('s', 'http://www.wikidata.org/entity/Q41582620'), ('name', 'Fiona M Walter')]
# [('p', 'http://www.wikidata.org/prop/direct/P108'), ('pname', 'employer'), ('s', 'http://www.wikidata.org/entity/Q47708567'), ('name', 'Esteve Corbera')]
# [('p', 'http://www.wikidata.org/prop/direct/P108'), ('pname', 'employer'), ('s', 'http://www.wikidata.org/entity/Q48294679'), ('name', 'John Adams')]
# [('p', 'http://www.wikidata.org/prop/direct/P108'), ('pname', 'employer'), ('s', 'http://www.wikidata.org/entity/Q55112032'), ('name', 'Vasanti Jadva')]
# [('p', 'http://www.wikidata.org/prop/direct/P108'), ('pname', 'employer'), ('s', 'http://www.wikidata.org/entity/Q59149082'), ('name', 'Lucy Blake')]
# [('p', 'http://www.wikidata.org/prop/direct/P108'), ('pname', 'employer'), ('s', 'http://www.wikidata.org/entity/Q42776540'), ('name', 'Jose C R Silva')]
# [('p', 'http://www.wikidata.org/prop/direct/P108'), ('pname', 'employer'), ('s', 'http://www.wikidata.org/entity/Q47503864'), ('name', 'Francesco Boselli')]
# [('p', 'http://www.wikidata.org/prop/direct/P108'), ('pname', 'employer'), ('s', 'http://www.wikidata.org/entity/Q89031346'), ('name', 'Clément Bouton')]
# [('p', 'http://www.wikidata.org/prop/direct/P108'), ('pname', 'employer'), ('s', 'http://www.wikidata.org/entity/Q45408437'), ('name', 'Alice E. Denton')]
# [('p', 'http://www.wikidata.org/prop/direct/P108'), ('pname', 'employer'), ('s', 'http://www.wikidata.org/entity/Q38319797'), ('name', 'Claire M Gillan')]
# [('p', 'http://www.wikidata.org/prop/direct/P108'), ('pname', 'employer'), ('s', 'http://www.wikidata.org/entity/Q29950041'), ('name', 'Alexandra Zieritz')]
# [('p', 'http://www.wikidata.org/prop/direct/P108'), ('pname', 'employer'), ('s', 'http://www.wikidata.org/entity/Q48060626'), ('name', 'Zoe A Dyson')]
# [('p', 'http://www.wikidata.org/prop/direct/P108'), ('pname', 'employer'), ('s', 'http://www.wikidata.org/entity/Q57908076'), ('name', 'Paul J Gates')]
# 100

# %%
# aim: explore the objects with property 'member of' in relation with 'University of Cambridge'
# result: found just one object and it's a comic character...
queryString = """
SELECT DISTINCT ?p ?pname ?s ?name
WHERE {
   # bind something
   # ?s ?p wd:Q35794 .
   # get the label
   # ?p sc:name ?pname .
   # ?s sc:name ?name .
   FILTER (?p IN (wdt:P463))
}
LIMIT 30
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P463'), ('pname', 'member of'), ('s', 'http://www.wikidata.org/entity/Q7861585'), ('name', 'Tyrone Cash')]
# 1

# %%
# aim: explore the objects with property 'work location' in relation with 'University of Cambridge'
# result: found just few objects
queryString = """
SELECT DISTINCT ?p ?pname ?s ?name
WHERE {
   # bind something
   # ?s ?p wd:Q35794 .
   # get the label
   # ?p sc:name ?pname .
   # ?s sc:name ?name .
   FILTER (?p IN (wdt:P937))
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P937'), ('pname', 'work location'), ('s', 'http://www.wikidata.org/entity/Q29609215'), ('name', 'Isaiah (Shy) Arkin')]
# [('p', 'http://www.wikidata.org/prop/direct/P937'), ('pname', 'work location'), ('s', 'http://www.wikidata.org/entity/Q98276775'), ('name', 'John Lee')]
# [('p', 'http://www.wikidata.org/prop/direct/P937'), ('pname', 'work location'), ('s', 'http://www.wikidata.org/entity/Q5739815'), ('name', 'Herman Hedwig Bernard')]
# [('p', 'http://www.wikidata.org/prop/direct/P937'), ('pname', 'work location'), ('s', 'http://www.wikidata.org/entity/Q23761569'), ('name', 'Ralph Symons')]
# 4

# %%
# aim: explore the objects with property 'professorship' in relation with 'University of Cambridge'
# result: found just few objects
queryString = """
SELECT DISTINCT ?p ?pname ?s ?name
WHERE {
   # bind something
   # ?s ?p wd:Q35794 .
   # get the label
   # ?p sc:name ?pname .
   # ?s sc:name ?name .
   FILTER (?p IN (wdt:P803))
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P803'), ('pname', 'professorship'), ('s', 'http://www.wikidata.org/entity/Q75349437'), ('name', 'Friedrich Max Müller')]
# [('p', 'http://www.wikidata.org/prop/direct/P803'), ('pname', 'professorship'), ('s', 'http://www.wikidata.org/entity/Q532695'), ('name', 'Michael Levey')]
# 2

# %%
# aim: get all the persons who worked both as university professors and computer scientists
# result: we found persons who worked both as university professors and computer scientists
queryString = """
SELECT DISTINCT ?person ?personname
WHERE {
   # bind something
   # ?person wdt:P106 ?job1 ;
           wdt:P106 ?job2 ;
           sc:name ?personname .
           
           
   #the person must be a computer scientist and a university teacher
   FILTER ((?job1 = wd:Q82594) && (?job2 = wd:Q1622272))
}
LIMIT 200
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('person', 'http://www.wikidata.org/entity/Q8190500'), ('personname', 'Seinosuke Toda')]
# [('person', 'http://www.wikidata.org/entity/Q92669'), ('personname', 'Jeffrey Shallit')]
# [('person', 'http://www.wikidata.org/entity/Q15917430'), ('personname', 'A. Ollongren')]
# [('person', 'http://www.wikidata.org/entity/Q16216373'), ('personname', 'Klaus Fuchs-Kittowski')]
# [('person', 'http://www.wikidata.org/entity/Q32772993'), ('personname', 'Dawson Engler')]
# [('person', 'http://www.wikidata.org/entity/Q92881'), ('personname', 'Douglas McIlroy')]
# [('person', 'http://www.wikidata.org/entity/Q173714'), ('personname', 'Max Euwe')]
# [('person', 'http://www.wikidata.org/entity/Q19296289'), ('personname', 'Michael Backes')]
# [('person', 'http://www.wikidata.org/entity/Q6899861'), ('personname', 'Moni Naor')]
# [('person', 'http://www.wikidata.org/entity/Q433933'), ('personname', 'Vincent Rijmen')]
# [('person', 'http://www.wikidata.org/entity/Q578036'), ('personname', 'Ron Rivest')]
# [('person', 'http://www.wikidata.org/entity/Q30135279'), ('personname', 'Amparo Alonso Betanzos')]
# [('person', 'http://www.wikidata.org/entity/Q19364605'), ('personname', 'Peter Stone')]
# [('person', 'http://www.wikidata.org/entity/Q27907660'), ('personname', 'Sebastian Risi')]
# [('person', 'http://www.wikidata.org/entity/Q67220557'), ('personname', 'Kenneth O. Stanley')]
# [('person', 'http://www.wikidata.org/entity/Q17386431'), ('personname', 'Petra Mutzel')]
# [('person', 'http://www.wikidata.org/entity/Q1443564'), ('personname', 'Frank Klawonn')]
# [('person', 'http://www.wikidata.org/entity/Q178577'), ('personname', 'Norbert Wiener')]
# [('person', 'http://www.wikidata.org/entity/Q1398547'), ('personname', 'Solomon W. Golomb')]
# [('person', 'http://www.wikidata.org/entity/Q1691718'), ('personname', 'Joel Spencer')]
# [('person', 'http://www.wikidata.org/entity/Q3229792'), ('personname', 'Leonidas J. Guibas')]
# [('person', 'http://www.wikidata.org/entity/Q66656'), ('personname', 'Rudolf Bayer')]
# [('person', 'http://www.wikidata.org/entity/Q92983'), ('personname', 'Robert Sedgewick')]
# [('person', 'http://www.wikidata.org/entity/Q319308'), ('personname', 'Douglas Hofstadter')]
# [('person', 'http://www.wikidata.org/entity/Q1819322'), ('personname', 'Leonhard Dobschütz')]
# [('person', 'http://www.wikidata.org/entity/Q2272611'), ('personname', 'Sergej Gorlač')]
# [('person', 'http://www.wikidata.org/entity/Q92643'), ('personname', 'Robin Milner')]
# [('person', 'http://www.wikidata.org/entity/Q18012465'), ('personname', 'Hans Zantema')]
# [('person', 'http://www.wikidata.org/entity/Q28123854'), ('personname', 'Shilad Sen')]
# [('person', 'http://www.wikidata.org/entity/Q28950249'), ('personname', 'Nikolaos Papanikolopoulos')]
# [('person', 'http://www.wikidata.org/entity/Q7237405'), ('personname', 'Pradeep Khosla')]
# [('person', 'http://www.wikidata.org/entity/Q92675'), ('personname', 'Takeo Kanade')]
# [('person', 'http://www.wikidata.org/entity/Q92735'), ('personname', 'Jürgen Schmidhuber')]
# [('person', 'http://www.wikidata.org/entity/Q11749'), ('personname', 'Lydia Kavraki')]
# [('person', 'http://www.wikidata.org/entity/Q1395570'), ('personname', 'Karina Morgenstern')]
# [('person', 'http://www.wikidata.org/entity/Q92611'), ('personname', 'Haskell Curry')]
# [('person', 'http://www.wikidata.org/entity/Q92704'), ('personname', 'Charles Colbourn')]
# [('person', 'http://www.wikidata.org/entity/Q86839269'), ('personname', 'Bennett Landman')]
# [('person', 'http://www.wikidata.org/entity/Q15266945'), ('personname', 'Leslie Carr')]
# [('person', 'http://www.wikidata.org/entity/Q62899'), ('personname', 'Steve Mann')]
# [('person', 'http://www.wikidata.org/entity/Q11609'), ('personname', 'Shafrira Goldwasser')]
# [('person', 'http://www.wikidata.org/entity/Q153224'), ('personname', 'Andrey Kolmogorov')]
# [('person', 'http://www.wikidata.org/entity/Q15430022'), ('personname', 'Gerhard Lustig')]
# [('person', 'http://www.wikidata.org/entity/Q16745311'), ('personname', 'Irene Greif')]
# [('person', 'http://www.wikidata.org/entity/Q1680268'), ('personname', 'James Demmel')]
# [('person', 'http://www.wikidata.org/entity/Q204815'), ('personname', 'Marvin Minsky')]
# [('person', 'http://www.wikidata.org/entity/Q2175555'), ('personname', 'Rul Gunzenhäuser')]
# [('person', 'http://www.wikidata.org/entity/Q313454'), ('personname', 'Jan Łukasiewicz')]
# [('person', 'http://www.wikidata.org/entity/Q335027'), ('personname', 'Seymour Papert')]
# [('person', 'http://www.wikidata.org/entity/Q41390'), ('personname', 'Kurt Gödel')]
# [('person', 'http://www.wikidata.org/entity/Q4701072'), ('personname', 'Akinori Yonezawa')]
# [('person', 'http://www.wikidata.org/entity/Q5217654'), ('personname', 'Daniel Jackson')]
# [('person', 'http://www.wikidata.org/entity/Q5218783'), ('personname', 'Daniel Sleator')]
# [('person', 'http://www.wikidata.org/entity/Q5669903'), ('personname', 'Harry Huskey')]
# [('person', 'http://www.wikidata.org/entity/Q60215473'), ('personname', 'Charles Lee Isbell, Jr.')]
# [('person', 'http://www.wikidata.org/entity/Q6737327'), ('personname', 'Maja Mataric')]
# [('person', 'http://www.wikidata.org/entity/Q68604'), ('personname', 'Friedrich L. Bauer')]
# [('person', 'http://www.wikidata.org/entity/Q8006908'), ('personname', 'William Clinger')]
# [('person', 'http://www.wikidata.org/entity/Q90046'), ('personname', 'Wolfgang Pree')]
# [('person', 'http://www.wikidata.org/entity/Q92628'), ('personname', 'Juris Hartmanis')]
# [('person', 'http://www.wikidata.org/entity/Q92644'), ('personname', 'Butler Lampson')]
# [('person', 'http://www.wikidata.org/entity/Q92646'), ('personname', 'John Henry Holland')]
# [('person', 'http://www.wikidata.org/entity/Q92690'), ('personname', 'Harald Ganzinger')]
# [('person', 'http://www.wikidata.org/entity/Q92713'), ('personname', 'Alan Ashton')]
# [('person', 'http://www.wikidata.org/entity/Q92742'), ('personname', 'Alan Kay')]
# [('person', 'http://www.wikidata.org/entity/Q92756'), ('personname', 'Johan Håstad')]
# [('person', 'http://www.wikidata.org/entity/Q92760'), ('personname', 'Claude Shannon')]
# [('person', 'http://www.wikidata.org/entity/Q92776'), ('personname', 'Steve Furber')]
# [('person', 'http://www.wikidata.org/entity/Q92782'), ('personname', 'William Kahan')]
# [('person', 'http://www.wikidata.org/entity/Q92783'), ('personname', 'Fred Cohen')]
# [('person', 'http://www.wikidata.org/entity/Q92798'), ('personname', 'David E. Goldberg')]
# [('person', 'http://www.wikidata.org/entity/Q92805'), ('personname', 'Umesh Vazirani')]
# [('person', 'http://www.wikidata.org/entity/Q92809'), ('personname', 'Rodney Brooks')]
# [('person', 'http://www.wikidata.org/entity/Q92845'), ('personname', 'László Babai')]
# [('person', 'http://www.wikidata.org/entity/Q92867'), ('personname', 'Ronald V. Book')]
# [('person', 'http://www.wikidata.org/entity/Q92880'), ('personname', 'Gerard Salton')]
# [('person', 'http://www.wikidata.org/entity/Q92909'), ('personname', 'Thomas Strothotte')]
# [('person', 'http://www.wikidata.org/entity/Q92913'), ('personname', 'Anja Feldmann')]
# [('person', 'http://www.wikidata.org/entity/Q92914'), ('personname', 'Klaus Samelson')]
# [('person', 'http://www.wikidata.org/entity/Q92951'), ('personname', 'Jacob T. Schwartz')]
# [('person', 'http://www.wikidata.org/entity/Q92962'), ('personname', 'Michael A. Arbib')]
# [('person', 'http://www.wikidata.org/entity/Q92981'), ('personname', 'Gerald Jay Sussman')]
# [('person', 'http://www.wikidata.org/entity/Q93051'), ('personname', 'Lov Grover')]
# [('person', 'http://www.wikidata.org/entity/Q93057'), ('personname', 'Neil Immerman')]
# [('person', 'http://www.wikidata.org/entity/Q93099'), ('personname', 'Robert S. Barton')]
# [('person', 'http://www.wikidata.org/entity/Q93106'), ('personname', 'Helmut Schreyer')]
# [('person', 'http://www.wikidata.org/entity/Q93109'), ('personname', 'Carl Hewitt')]
# [('person', 'http://www.wikidata.org/entity/Q93121'), ('personname', 'Tadao Kasami')]
# [('person', 'http://www.wikidata.org/entity/Q93149'), ('personname', 'Madhu Sudan')]
# [('person', 'http://www.wikidata.org/entity/Q11626'), ('personname', 'Wendy Hall')]
# [('person', 'http://www.wikidata.org/entity/Q11754'), ('personname', 'Maria Klawe')]
# [('person', 'http://www.wikidata.org/entity/Q1490424'), ('personname', 'Gabriele Kotsis')]
# [('person', 'http://www.wikidata.org/entity/Q17102488'), ('personname', 'Alexander L. Wolf')]
# [('person', 'http://www.wikidata.org/entity/Q16527011'), ('personname', 'Adolfo Guzmán Arenas')]
# [('person', 'http://www.wikidata.org/entity/Q17455'), ('personname', 'John von Neumann')]
# [('person', 'http://www.wikidata.org/entity/Q92626'), ('personname', 'Manuel Blum')]
# [('person', 'http://www.wikidata.org/entity/Q93030'), ('personname', 'Leon O. Chua')]
# [('person', 'http://www.wikidata.org/entity/Q92794'), ('personname', 'Jeffrey David Ullman')]
# [('person', 'http://www.wikidata.org/entity/Q221697'), ('personname', 'Hilary Putnam')]
# [('person', 'http://www.wikidata.org/entity/Q2632606'), ('personname', 'Gerrit Blaauw')]
# [('person', 'http://www.wikidata.org/entity/Q299595'), ('personname', 'Vannevar Bush')]
# [('person', 'http://www.wikidata.org/entity/Q92609'), ('personname', 'Fred Brooks')]
# [('person', 'http://www.wikidata.org/entity/Q738599'), ('personname', 'Assaf Naor')]
# [('person', 'http://www.wikidata.org/entity/Q468053'), ('personname', 'Susan Athey')]
# [('person', 'http://www.wikidata.org/entity/Q475614'), ('personname', 'Germund Dahlquist')]
# [('person', 'http://www.wikidata.org/entity/Q8556'), ('personname', 'Edsger W. Dijkstra')]
# [('person', 'http://www.wikidata.org/entity/Q830978'), ('personname', 'László Kalmár')]
# [('person', 'http://www.wikidata.org/entity/Q93042'), ('personname', 'Richard P. Brent')]
# [('person', 'http://www.wikidata.org/entity/Q560818'), ('personname', 'David Slepian')]
# [('person', 'http://www.wikidata.org/entity/Q6198902'), ('personname', 'Jim Whitehead')]
# [('person', 'http://www.wikidata.org/entity/Q7149157'), ('personname', 'Paul B. Kantor')]
# [('person', 'http://www.wikidata.org/entity/Q944937'), ('personname', 'Henry Samueli')]
# [('person', 'http://www.wikidata.org/entity/Q92596'), ('personname', 'Edgar F. Codd')]
# [('person', 'http://www.wikidata.org/entity/Q687404'), ('personname', 'Armin Biere')]
# [('person', 'http://www.wikidata.org/entity/Q1078285'), ('personname', 'Nicolaas Govert de Bruijn')]
# [('person', 'http://www.wikidata.org/entity/Q1928287'), ('personname', 'Michael Krapp')]
# [('person', 'http://www.wikidata.org/entity/Q1944655'), ('personname', 'Monika Henzinger')]
# [('person', 'http://www.wikidata.org/entity/Q57403'), ('personname', 'Wilhelm Schickard')]
# [('person', 'http://www.wikidata.org/entity/Q2473189'), ('personname', 'Udo Helmbrecht')]
# [('person', 'http://www.wikidata.org/entity/Q93087'), ('personname', 'Jacques Stern')]
# [('person', 'http://www.wikidata.org/entity/Q1384896'), ('personname', 'Marcel-Paul Schützenberger')]
# [('person', 'http://www.wikidata.org/entity/Q476466'), ('personname', 'Martin Edward Hellman')]
# [('person', 'http://www.wikidata.org/entity/Q6775113'), ('personname', 'Martin Campbell-Kelly')]
# [('person', 'http://www.wikidata.org/entity/Q21005460'), ('personname', 'Craig Chambers')]
# [('person', 'http://www.wikidata.org/entity/Q71458457'), ('personname', 'Pat Langley')]
# [('person', 'http://www.wikidata.org/entity/Q1292266'), ('personname', 'Edward Fredkin')]
# [('person', 'http://www.wikidata.org/entity/Q92745'), ('personname', 'Ole-Johan Dahl')]
# [('person', 'http://www.wikidata.org/entity/Q1675808'), ('personname', 'Ivo Vondrák')]
# [('person', 'http://www.wikidata.org/entity/Q92697'), ('personname', 'Yiannis N. Moschovakis')]
# [('person', 'http://www.wikidata.org/entity/Q3308285'), ('personname', 'Michael I. Jordan')]
# [('person', 'http://www.wikidata.org/entity/Q21264478'), ('personname', 'Olga Sorkine-Hornung')]
# [('person', 'http://www.wikidata.org/entity/Q24054846'), ('personname', 'Sean Follmer')]
# [('person', 'http://www.wikidata.org/entity/Q56427689'), ('personname', 'Jarosław Duda')]
# [('person', 'http://www.wikidata.org/entity/Q41187382'), ('personname', 'David L. Dill')]
# [('person', 'http://www.wikidata.org/entity/Q47134273'), ('personname', 'Niko Beerenwinkel')]
# [('person', 'http://www.wikidata.org/entity/Q7290597'), ('personname', 'Ran Libeskind-Hadas')]
# [('person', 'http://www.wikidata.org/entity/Q28862271'), ('personname', 'Nataša Jonoska')]
# [('person', 'http://www.wikidata.org/entity/Q20830617'), ('personname', 'Loren Terveen')]
# [('person', 'http://www.wikidata.org/entity/Q2846695'), ('personname', 'Andrew Y. Ng')]
# [('person', 'http://www.wikidata.org/entity/Q3017847'), ('personname', 'David Eppstein')]
# [('person', 'http://www.wikidata.org/entity/Q92963'), ('personname', 'Rajeev Motwani')]
# [('person', 'http://www.wikidata.org/entity/Q18587349'), ('personname', 'Janez Demšar')]
# [('person', 'http://www.wikidata.org/entity/Q17457'), ('personname', 'Donald Knuth')]
# [('person', 'http://www.wikidata.org/entity/Q18618630'), ('personname', 'Markus Krötzsch')]
# [('person', 'http://www.wikidata.org/entity/Q80'), ('personname', 'Tim Berners-Lee')]
# [('person', 'http://www.wikidata.org/entity/Q92743'), ('personname', 'Vint Cerf')]
# [('person', 'http://www.wikidata.org/entity/Q11612'), ('personname', 'Susan L. Graham')]
# [('person', 'http://www.wikidata.org/entity/Q102293308'), ('personname', 'R. Michael Young')]
# [('person', 'http://www.wikidata.org/entity/Q14096'), ('personname', 'Johanna Moore')]
# [('person', 'http://www.wikidata.org/entity/Q14218'), ('personname', 'Colette Rolland')]
# [('person', 'http://www.wikidata.org/entity/Q14263'), ('personname', 'Ileana Streinu')]
# [('person', 'http://www.wikidata.org/entity/Q5238306'), ('personname', 'David P. Dobkin')]
# [('person', 'http://www.wikidata.org/entity/Q557018'), ('personname', 'Ken Kutaragi')]
# [('person', 'http://www.wikidata.org/entity/Q11590'), ('personname', 'Phyllis Fox')]
# [('person', 'http://www.wikidata.org/entity/Q49823'), ('personname', 'Dana Scott')]
# [('person', 'http://www.wikidata.org/entity/Q181529'), ('personname', 'Herbert Alexander Simon')]
# [('person', 'http://www.wikidata.org/entity/Q439245'), ('personname', 'Allen Newell')]
# [('person', 'http://www.wikidata.org/entity/Q21598261'), ('personname', 'Michael Weber')]
# [('person', 'http://www.wikidata.org/entity/Q840535'), ('personname', 'Robert J. McEliece')]
# [('person', 'http://www.wikidata.org/entity/Q93086'), ('personname', 'Nikolaus Joachim Lehmann')]
# [('person', 'http://www.wikidata.org/entity/Q1227946'), ('personname', 'Dirk Loomans')]
# [('person', 'http://www.wikidata.org/entity/Q1237798'), ('personname', 'Dominik Heider')]
# [('person', 'http://www.wikidata.org/entity/Q1243222'), ('personname', 'Thomas Lengauer')]
# [('person', 'http://www.wikidata.org/entity/Q92638'), ('personname', 'Robert Tarjan')]
# [('person', 'http://www.wikidata.org/entity/Q1793667'), ('personname', 'Kurt Hornik')]
# [('person', 'http://www.wikidata.org/entity/Q2020107'), ('personname', 'Oliver Johannes Bott')]
# [('person', 'http://www.wikidata.org/entity/Q2025920'), ('personname', 'Coenraad Bron')]
# [('person', 'http://www.wikidata.org/entity/Q47479573'), ('personname', 'Andreas Günter Weber')]
# [('person', 'http://www.wikidata.org/entity/Q3839553'), ('personname', 'Luigi Dadda')]
# [('person', 'http://www.wikidata.org/entity/Q38692969'), ('personname', 'Alexander Ilyin')]
# [('person', 'http://www.wikidata.org/entity/Q4299718'), ('personname', 'Evgeny Moiseev')]
# [('person', 'http://www.wikidata.org/entity/Q11779'), ('personname', 'Nancy Lynch')]
# [('person', 'http://www.wikidata.org/entity/Q6224559'), ('personname', 'John C. Mitchell')]
# [('person', 'http://www.wikidata.org/entity/Q7146188'), ('personname', 'Patrick C. Fischer')]
# [('person', 'http://www.wikidata.org/entity/Q92736'), ('personname', 'Anant Agarwal')]
# [('person', 'http://www.wikidata.org/entity/Q2896470'), ('personname', 'Dan Boneh')]
# [('person', 'http://www.wikidata.org/entity/Q314308'), ('personname', 'John Vincent Atanasoff')]
# [('person', 'http://www.wikidata.org/entity/Q90313'), ('personname', 'Kurt Mehlhorn')]
# [('person', 'http://www.wikidata.org/entity/Q517898'), ('personname', 'Teuvo Kohonen')]
# [('person', 'http://www.wikidata.org/entity/Q92847'), ('personname', 'Abraham Lempel')]
# [('person', 'http://www.wikidata.org/entity/Q957439'), ('personname', 'Jacob Ziv')]
# [('person', 'http://www.wikidata.org/entity/Q92618'), ('personname', 'Peter Naur')]
# [('person', 'http://www.wikidata.org/entity/Q2522623'), ('personname', 'Victor Zue')]
# [('person', 'http://www.wikidata.org/entity/Q20492609'), ('personname', 'Txelo Ruiz-Vazquez')]
# [('person', 'http://www.wikidata.org/entity/Q5653782'), ('personname', 'Harald Haas')]
# [('person', 'http://www.wikidata.org/entity/Q92601'), ('personname', 'Nicholas Negroponte')]
# [('person', 'http://www.wikidata.org/entity/Q23883702'), ('personname', 'John Regehr')]
# [('person', 'http://www.wikidata.org/entity/Q16477'), ('personname', 'Dorothea Wagner')]
# [('person', 'http://www.wikidata.org/entity/Q224372'), ('personname', 'I. J. Good')]
# [('person', 'http://www.wikidata.org/entity/Q15835702'), ('personname', 'Moses Charikar')]
# [('person', 'http://www.wikidata.org/entity/Q1686462'), ('personname', 'Jeffrey Lagarias')]
# [('person', 'http://www.wikidata.org/entity/Q7381584'), ('personname', 'Russell Impagliazzo')]
# [('person', 'http://www.wikidata.org/entity/Q92823'), ('personname', 'Edward Feigenbaum')]
# [('person', 'http://www.wikidata.org/entity/Q23506572'), ('personname', 'George Karypis')]
# [('person', 'http://www.wikidata.org/entity/Q27559542'), ('personname', 'Alessandra Carbone')]
# [('person', 'http://www.wikidata.org/entity/Q92700'), ('personname', 'Stephen Brewster')]
# [('person', 'http://www.wikidata.org/entity/Q23039810'), ('personname', 'Samuel Kaski')]
# [('person', 'http://www.wikidata.org/entity/Q28900'), ('personname', 'John George Kemeny')]
# [('person', 'http://www.wikidata.org/entity/Q43768'), ('personname', 'Heinz Zemanek')]
# [('person', 'http://www.wikidata.org/entity/Q92741'), ('personname', 'Alonzo Church')]
# 200

# %%
# aim: get all the persons who worked both as university professors and computer scientists with the property 'employer' related to 'University of Cambridge'
# result: we found persons who were professors and computer scientists at the University of Cambridge
queryString = """
SELECT DISTINCT ?person ?personname
WHERE {
   # bind something
   # ?person wdt:P106 ?job1 ;
           wdt:P106 ?job2 ;
           sc:name ?personname ;
           wdt:P108 wd:Q35794 .
           
           
   #the person must be a 'computer scientist' and a 'university teacher' or 'lecturer'
   FILTER ((?job1 = wd:Q82594) && (?job2 IN(wd:Q1622272,wd:Q1569495 ))) .
}
LIMIT 10
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('person', 'http://www.wikidata.org/entity/Q46633'), ('personname', 'Charles Babbage')]
# [('person', 'http://www.wikidata.org/entity/Q62857'), ('personname', 'Maurice Wilkes')]
# [('person', 'http://www.wikidata.org/entity/Q451770'), ('personname', 'Douglas Hartree')]
# [('person', 'http://www.wikidata.org/entity/Q4707402'), ('personname', 'Alan Mycroft')]
# [('person', 'http://www.wikidata.org/entity/Q10348961'), ('personname', 'Peter Russell')]
# [('person', 'http://www.wikidata.org/entity/Q63126308'), ('personname', 'Peter Földiák')]
# [('person', 'http://www.wikidata.org/entity/Q216811'), ('personname', 'John Venn')]
# [('person', 'http://www.wikidata.org/entity/Q100586732'), ('personname', 'Ferenc Huszár')]
# [('person', 'http://www.wikidata.org/entity/Q316330'), ('personname', 'Daniel Bell')]
# 9

# %%
# aim: get all the persons who worked as computer scientists with the property 'employer' related to 'University of Cambridge'
# result: we found persons who were computer scientists at the University of Cambridge but this might mean that they were only researchers so we choose the
#         previous query to fulfill the objective of this task
queryString = """
SELECT DISTINCT ?person ?personname
WHERE {
   # bind something
   # ?person wdt:P106 ?job1 ;
           sc:name ?personname ;
           wdt:P108 wd:Q35794 .
           
           
   #the person must be a computer scientist
   FILTER (?job1 = wd:Q82594) .
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('person', 'http://www.wikidata.org/entity/Q92944'), ('personname', 'David Wheeler')]
# [('person', 'http://www.wikidata.org/entity/Q7251'), ('personname', 'Alan Turing')]
# [('person', 'http://www.wikidata.org/entity/Q365578'), ('personname', 'Nathan Myhrvold')]
# [('person', 'http://www.wikidata.org/entity/Q446862'), ('personname', 'David J. C. MacKay')]
# [('person', 'http://www.wikidata.org/entity/Q92431724'), ('personname', 'Andrew Pitts')]
# [('person', 'http://www.wikidata.org/entity/Q46633'), ('personname', 'Charles Babbage')]
# [('person', 'http://www.wikidata.org/entity/Q7259'), ('personname', 'Ada Lovelace')]
# [('person', 'http://www.wikidata.org/entity/Q62857'), ('personname', 'Maurice Wilkes')]
# [('person', 'http://www.wikidata.org/entity/Q7176624'), ('personname', 'Peter Robinson')]
# [('person', 'http://www.wikidata.org/entity/Q451770'), ('personname', 'Douglas Hartree')]
# [('person', 'http://www.wikidata.org/entity/Q6135125'), ('personname', 'James H. Davenport')]
# [('person', 'http://www.wikidata.org/entity/Q4707402'), ('personname', 'Alan Mycroft')]
# [('person', 'http://www.wikidata.org/entity/Q10348961'), ('personname', 'Peter Russell')]
# [('person', 'http://www.wikidata.org/entity/Q63126308'), ('personname', 'Peter Földiák')]
# [('person', 'http://www.wikidata.org/entity/Q216811'), ('personname', 'John Venn')]
# [('person', 'http://www.wikidata.org/entity/Q5538146'), ('personname', 'George Coulouris')]
# [('person', 'http://www.wikidata.org/entity/Q6504468'), ('personname', 'Lawrence Paulson')]
# [('person', 'http://www.wikidata.org/entity/Q15989962'), ('personname', 'Neil Dodgson')]
# [('person', 'http://www.wikidata.org/entity/Q62036851'), ('personname', 'Mateja Jamnik')]
# [('person', 'http://www.wikidata.org/entity/Q62004384'), ('personname', 'Heidi Howard')]
# [('person', 'http://www.wikidata.org/entity/Q20831555'), ('personname', 'Jean Bacon')]
# [('person', 'http://www.wikidata.org/entity/Q5238377'), ('personname', 'David Park')]
# [('person', 'http://www.wikidata.org/entity/Q92873'), ('personname', 'Roger Michael Needham')]
# [('person', 'http://www.wikidata.org/entity/Q100586732'), ('personname', 'Ferenc Huszár')]
# [('person', 'http://www.wikidata.org/entity/Q6766466'), ('personname', "Mark A. O'Neill")]
# [('person', 'http://www.wikidata.org/entity/Q81842478'), ('personname', 'Paula Buttery')]
# [('person', 'http://www.wikidata.org/entity/Q57244353'), ('personname', 'Simone Teufel')]
# [('person', 'http://www.wikidata.org/entity/Q81520088'), ('personname', 'Alice Hutchings')]
# [('person', 'http://www.wikidata.org/entity/Q97571377'), ('personname', 'Roberto Cipolla')]
# [('person', 'http://www.wikidata.org/entity/Q5534365'), ('personname', 'Geoff Walsham')]
# [('person', 'http://www.wikidata.org/entity/Q316330'), ('personname', 'Daniel Bell')]
# [('person', 'http://www.wikidata.org/entity/Q30122679'), ('personname', 'Steve Young')]
# [('person', 'http://www.wikidata.org/entity/Q16489'), ('personname', 'Sophie Wilson')]
# [('person', 'http://www.wikidata.org/entity/Q21708036'), ('personname', 'Richard Pankhurst')]
# [('person', 'http://www.wikidata.org/entity/Q5982621'), ('personname', 'Ian Pratt')]
# [('person', 'http://www.wikidata.org/entity/Q7821956'), ('personname', 'Tony Brooker')]
# 36

# %% [markdown]
# Final query for this task

# %%
# aim: get all the persons who worked both as university professors and computer scientists with the property 'employer' related to 'University of Cambridge'
# result: we found persons who were professors and computer scientists at the University of Cambridge
queryString = """
SELECT DISTINCT ?person ?personname
WHERE {
   # bind something
   # ?person wdt:P106 ?job1 ;
           wdt:P106 ?job2 ;
           sc:name ?personname ;
           wdt:P108 wd:Q35794 .
           
           
   #the person must be a 'computer scientist' and a 'university teacher' or 'lecturer'
   FILTER ((?job1 = wd:Q82594) && (?job2 IN(wd:Q1622272,wd:Q1569495 ))) .
}
LIMIT 10
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('person', 'http://www.wikidata.org/entity/Q46633'), ('personname', 'Charles Babbage')]
# [('person', 'http://www.wikidata.org/entity/Q62857'), ('personname', 'Maurice Wilkes')]
# [('person', 'http://www.wikidata.org/entity/Q451770'), ('personname', 'Douglas Hartree')]
# [('person', 'http://www.wikidata.org/entity/Q4707402'), ('personname', 'Alan Mycroft')]
# [('person', 'http://www.wikidata.org/entity/Q10348961'), ('personname', 'Peter Russell')]
# [('person', 'http://www.wikidata.org/entity/Q63126308'), ('personname', 'Peter Földiák')]
# [('person', 'http://www.wikidata.org/entity/Q216811'), ('personname', 'John Venn')]
# [('person', 'http://www.wikidata.org/entity/Q100586732'), ('personname', 'Ferenc Huszár')]
# [('person', 'http://www.wikidata.org/entity/Q316330'), ('personname', 'Daniel Bell')]
# 9

# %% [markdown]
# ## Task 7
# Find all the computer scientists who wrote at least 5 books (please consider only the instances of book, exclude "literary work" or other type of work related to books). Return the IRI and name of the computer scientist and the number of books.

# %%
# aim: since we don't have particular properties that might refer to books, we try to look for some possible class containing the word 'book'
# result: we found something that might be related to books
queryString = """
SELECT DISTINCT ?book ?bookname
WHERE {
   # bind something
   # ?book sc:name ?bookname .
           
           
   FILTER REGEX(?bookname, "book", "i") .
}
LIMIT 10
"""
print("Results")
x=run_query(queryString)
# Out:
# Results
# [('book', 'http://www.wikidata.org/entity/Q8130203'), ('bookname', 'Category:1920s books')]
# [('book', 'http://www.wikidata.org/entity/Q8212873'), ('bookname', 'Category:810s books')]
# [('book', 'http://www.wikidata.org/entity/Q8213977'), ('bookname', 'Category:970s books')]
# [('book', 'http://www.wikidata.org/entity/Q8227293'), ('bookname', 'Category:Aikido books')]
# [('book', 'http://www.wikidata.org/entity/Q8352313'), ('bookname', 'Category:Cengage books')]
# [('book', 'http://www.wikidata.org/entity/Q8361917'), ('bookname', 'Category:Danish booksellers')]
# [('book', 'http://www.wikidata.org/entity/Q8362395'), ('bookname', "Category:Chinese children's books")]
# [('book', 'http://www.wikidata.org/entity/Q8366938'), ('bookname', 'Category:Christian theology books')]
# [('book', 'http://www.wikidata.org/entity/Q8376756'), ('bookname', 'Category:Dinosaur books')]
# [('book', 'http://www.wikidata.org/entity/Q8385961'), ('bookname', 'Category:Doctor Who book covers')]
# 10

# %%
# aim: get the properties of 'Category:Dinosaur books'
# result: we found the 'instance of' property: it might mean that it's instance of something related to books
queryString = """
SELECT DISTINCT ?p ?pname
WHERE {
   # bind something
   wd:Q8376756 ?p ?obj .
   # ?p sc:name ?pname .
}
LIMIT 100
"""
print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pname', 'instance of')]
# 1

# %%
# aim: check the property 'instance of' of 'Category:Dinosaur books'
# result: we found it's a 'Wikimedia category'
queryString = """
SELECT DISTINCT ?obj ?oname
WHERE {
   # bind something
   wd:Q8376756 wdt:P31 ?obj .
   # ?obj sc:name ?oname .
}
LIMIT 100
"""
print("Results")
x=run_query(queryString)
# Out:
# Results
# [('obj', 'http://www.wikidata.org/entity/Q4167836'), ('oname', 'Wikimedia category')]
# 1

# %%
# aim: check if 'Category:Dinosaur books' might be related to books
# result: no results. We need to choose another way to proceed
queryString = """
SELECT DISTINCT ?s ?sname
WHERE {
   # bind something
   # ?s ?p wd:Q8376756 .
   # ?s sc:name ?sname .
}
LIMIT 100
"""
print("Results")
x=run_query(queryString)
# Out:
# Results
# Empty

# %%
# aim: since we don't have particular properties that might refer to books, we try to look for some possible class containing the word 'book' but not containing the word 'Category:'
# result: we found something that might be related to books but these are not actually book at first glance...
queryString = """
SELECT DISTINCT ?book ?bookname
WHERE {
   # bind something
   # ?book sc:name ?bookname .
           
           
   FILTER REGEX(?bookname, "book", "i") .
   FILTER (!REGEX(?bookname, "Category:")) .
}
LIMIT 10
"""
print("Results")
x=run_query(queryString)
# Out:
# Results
# [('book', 'http://www.wikidata.org/entity/Q2594405'), ('bookname', 'Modern Age of Comic Books')]
# [('book', 'http://www.wikidata.org/entity/Q3430019'), ('bookname', 'Redbook')]
# [('book', 'http://www.wikidata.org/entity/Q8614441'), ('bookname', 'Help:Books/License')]
# [('book', 'http://www.wikidata.org/entity/Q13865328'), ('bookname', 'Murder Book')]
# [('book', 'http://www.wikidata.org/entity/Q15753688'), ('bookname', 'Yearbook of European Law')]
# [('book', 'http://www.wikidata.org/entity/Q15759152'), ('bookname', 'Yearbook of Oriental Studies')]
# [('book', 'http://www.wikidata.org/entity/Q15759228'), ('bookname', 'Canadian Yearbook of International Law')]
# [('book', 'http://www.wikidata.org/entity/Q15759994'), ('bookname', 'Biblionews and Australian Notes and Queries: journal for book collectors')]
# [('book', 'http://www.wikidata.org/entity/Q15761830'), ('bookname', 'Vienna Yearbook of Population Research')]
# [('book', 'http://www.wikidata.org/entity/Q10876287'), ('bookname', 'Chung Hwa Book Company (Hong Kong)')]
# 10

# %%
# aim: look for a class containing the word 'book' that may contain possible instances of books
# result: we found a sketchbook, it might be related to a more general class 'book'
queryString = """
SELECT DISTINCT ?book ?bookname
WHERE {
   # bind something
   # ?book sc:name ?bookname .
   # ?obj wdt:P31 ?book .
           
           
   FILTER REGEX(?bookname, "book", "i") .
}
LIMIT 1
"""
print("Results")
x=run_query(queryString)
# Out:
# Results
# [('book', 'http://www.wikidata.org/entity/Q60520'), ('bookname', 'sketchbook')]
# 1

# %%
# aim: check the properties of 'sketchbook'
# result: the 'sketchbook' properties relate it more to something relate to paintings
queryString = """
SELECT DISTINCT ?p ?pname ?o ?oname
WHERE {
   # bind something
   wd:Q60520 ?p ?o .
   # ?p sc:name ?pname .
   # ?o sc:name ?oname .
}
LIMIT 1
"""
print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pname', 'has part'), ('o', 'http://www.wikidata.org/entity/Q5078274'), ('oname', 'sketch')]
# 1

# %%
# aim: look for a class containing the word 'book' that may contain possible subclasses (there could be classes like children book and so on...)
# result: we found workbook but a workbook is an electronic sheet to perform calculations so it can't be related to books
queryString = """
SELECT DISTINCT ?book ?bookname
WHERE {
   # bind something
   # ?book sc:name ?bookname .
   # ?obj wdt:P279 ?book .
           
           
   FILTER REGEX(?bookname, "book", "i") .
}
LIMIT 1
"""
print("Results")
x=run_query(queryString)
# Out:
# Results
# [('book', 'http://www.wikidata.org/entity/Q26853769'), ('bookname', 'workbook')]
# 1

# %%
# aim: look for a class containing the word 'book' that may contain possible subclasses (there could be classes like children book and so on...)
# result: we found workbook but a workbook is an electronic sheet to perform calculations so it can't be related to books
queryString = """
SELECT DISTINCT ?book ?bookname
WHERE {
   # bind something
   # ?book sc:name ?bookname .
   # ?obj wdt:P31 ?book .
   # ?obj ?pauthor ?author .
   # ?pauthor sc:name ?pauthorname
           
   FILTER REGEX(?bookname, "book", "i") .
   FILTER REGEX(?pauthorname, "author", "i") .
}
LIMIT 1
"""
print("Results")
x=run_query(queryString)
# Out:
# Results
# [('book', 'http://www.wikidata.org/entity/Q277759'), ('bookname', 'book series')]
# 1

# %%
# aim: look for a resource containing the word 'author'
# result: we didn't find an 'author' property...
queryString = """
SELECT DISTINCT ?p ?pname
WHERE {
   # bind something
   # ?p sc:name ?pname .
           
           
   FILTER REGEX(?pname, "author", "i") .
}
LIMIT 20
"""
print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/entity/Q788451'), ('pname', 'author citation')]
# [('p', 'http://www.wikidata.org/entity/Q8354433'), ('pname', 'Category:Certified albums by certifying authority')]
# [('p', 'http://www.wikidata.org/entity/Q8371763'), ('pname', 'Category:Delaware River and Bay Authority facilities')]
# [('p', 'http://www.wikidata.org/entity/Q8397920'), ('pname', 'Category:Communications authorities')]
# [('p', 'http://www.wikidata.org/entity/Q8458417'), ('pname', 'Category:Financial regulatory authorities of the United States')]
# [('p', 'http://www.wikidata.org/entity/Q15892203'), ('pname', 'Oxfordian theory of Shakespeare authorship')]
# [('p', 'http://www.wikidata.org/entity/Q8616115'), ('pname', 'Help:Wikipedia: The Missing Manual/Author and Publisher Information')]
# [('p', 'http://www.wikidata.org/entity/Q8675188'), ('pname', 'Category:New York State Thruway Authority')]
# [('p', 'http://www.wikidata.org/entity/Q8703893'), ('pname', 'Category:Santa Clara Valley Transportation Authority light rail lines')]
# [('p', 'http://www.wikidata.org/entity/Q8707683'), ('pname', 'Category:Oxfordian theory of Shakespeare authorship')]
# [('p', 'http://www.wikidata.org/entity/Q8709087'), ('pname', 'Category:Pages with authority control information')]
# [('p', 'http://www.wikidata.org/entity/Q8711570'), ('pname', 'Category:Palestinian National Authority election templates')]
# [('p', 'http://www.wikidata.org/entity/Q6935294'), ('pname', 'Mumbai Metropolitan Region Development Authority')]
# [('p', 'http://www.wikidata.org/entity/Q107742398'), ('pname', 'Wikidata property for authority control for athletics competitors')]
# [('p', 'http://www.wikidata.org/entity/Q15726996'), ('pname', 'Category:Authors-C')]
# [('p', 'http://www.wikidata.org/entity/Q15727063'), ('pname', 'Category:Authors-H')]
# [('p', 'http://www.wikidata.org/entity/Q15727079'), ('pname', 'Category:Authors-I')]
# [('p', 'http://www.wikidata.org/entity/Q15727139'), ('pname', 'Category:Authors-M')]
# [('p', 'http://www.wikidata.org/entity/Q15727232'), ('pname', 'Category:Authors-R')]
# [('p', 'http://www.wikidata.org/entity/Q15727737'), ('pname', 'Category:Authors-W')]
# 20

# %%
# aim: look for some possible resources containing the word 'book' but not containing the word 'Category:' with a higher LIMIT that has the property 'subclass of' that might link it
#      to a 'book' class
# result: we found an interesting resource called 'banned book' that might be a subclass of a possible book class
queryString = """
SELECT DISTINCT ?book ?bookname
WHERE {
   # bind something
   # ?book sc:name ?bookname .
   # ?book wdt:P279 ?subclass .
           
           
   FILTER REGEX(?bookname, "book", "i") .
   FILTER (!REGEX(?bookname, "Category:")) .
}
LIMIT 50
"""
print("Results")
x=run_query(queryString)
# Out:
# Results
# [('book', 'http://www.wikidata.org/entity/Q17048770'), ('bookname', 'Splatbook')]
# [('book', 'http://www.wikidata.org/entity/Q65770793'), ('bookname', 'banned book')]
# [('book', 'http://www.wikidata.org/entity/Q60520'), ('bookname', 'sketchbook')]
# [('book', 'http://www.wikidata.org/entity/Q22976748'), ('bookname', 'stamp book')]
# [('book', 'http://www.wikidata.org/entity/Q26853769'), ('bookname', 'workbook')]
# [('book', 'http://www.wikidata.org/entity/Q21818614'), ('bookname', 'liturgical book of the Roman Rite')]
# [('book', 'http://www.wikidata.org/entity/Q2477770'), ('bookname', 'Ultrabook')]
# [('book', 'http://www.wikidata.org/entity/Q488192'), ('bookname', 'MacBook Air')]
# [('book', 'http://www.wikidata.org/entity/Q22759'), ('bookname', 'book censorship')]
# [('book', 'http://www.wikidata.org/entity/Q105810973'), ('bookname', 'award for best book (by genre)')]
# [('book', 'http://www.wikidata.org/entity/Q2538131'), ('bookname', 'OER textbook')]
# [('book', 'http://www.wikidata.org/entity/Q1599788'), ('bookname', 'phrase book')]
# [('book', 'http://www.wikidata.org/entity/Q1027825'), ('bookname', 'choral book')]
# [('book', 'http://www.wikidata.org/entity/Q73501146'), ('bookname', 'Sune book')]
# [('book', 'http://www.wikidata.org/entity/Q4677625'), ('bookname', 'activity book')]
# [('book', 'http://www.wikidata.org/entity/Q29642842'), ('bookname', 'e-book reader software')]
# [('book', 'http://www.wikidata.org/entity/Q2005272'), ('bookname', 'Stonewall Book Award')]
# [('book', 'http://www.wikidata.org/entity/Q998550'), ('bookname', 'bookseller')]
# [('book', 'http://www.wikidata.org/entity/Q1106827'), ('bookname', 'coffee table book')]
# [('book', 'http://www.wikidata.org/entity/Q1320047'), ('bookname', 'book publisher')]
# [('book', 'http://www.wikidata.org/entity/Q1760610'), ('bookname', 'comic book')]
# [('book', 'http://www.wikidata.org/entity/Q604219'), ('bookname', 'photo-book')]
# [('book', 'http://www.wikidata.org/entity/Q128391'), ('bookname', 'comic book collecting')]
# [('book', 'http://www.wikidata.org/entity/Q20540385'), ('bookname', 'non-fiction book')]
# [('book', 'http://www.wikidata.org/entity/Q28050019'), ('bookname', 'list of best books')]
# [('book', 'http://www.wikidata.org/entity/Q1115655'), ('bookname', 'subnotebook')]
# [('book', 'http://www.wikidata.org/entity/Q178470'), ('bookname', 'netbook')]
# [('book', 'http://www.wikidata.org/entity/Q254554'), ('bookname', 'picture book')]
# [('book', 'http://www.wikidata.org/entity/Q107326062'), ('bookname', 'bookshelf')]
# [('book', 'http://www.wikidata.org/entity/Q1670087'), ('bookname', 'PowerBook G4')]
# [('book', 'http://www.wikidata.org/entity/Q214276'), ('bookname', 'MacBook Pro')]
# [('book', 'http://www.wikidata.org/entity/Q215857'), ('bookname', 'bookcase')]
# [('book', 'http://www.wikidata.org/entity/Q22702'), ('bookname', 'book burning')]
# [('book', 'http://www.wikidata.org/entity/Q3065317'), ('bookname', 'MacBook')]
# [('book', 'http://www.wikidata.org/entity/Q486053'), ('bookname', 'MacBook')]
# [('book', 'http://www.wikidata.org/entity/Q1136336'), ('bookname', 'Costa Book Awards')]
# [('book', 'http://www.wikidata.org/entity/Q367035'), ('bookname', 'address book')]
# [('book', 'http://www.wikidata.org/entity/Q998555'), ('bookname', 'book illustration')]
# [('book', 'http://www.wikidata.org/entity/Q1496857'), ('bookname', 'prayer book')]
# [('book', 'http://www.wikidata.org/entity/Q621319'), ('bookname', 'PowerBook G3')]
# [('book', 'http://www.wikidata.org/entity/Q638083'), ('bookname', 'PowerBook G3 Series (Wallstreet Series II)')]
# [('book', 'http://www.wikidata.org/entity/Q1650727'), ('bookname', 'song book')]
# [('book', 'http://www.wikidata.org/entity/Q81986407'), ('bookname', 'e-book file format')]
# [('book', 'http://www.wikidata.org/entity/Q2939758'), ('bookname', 'glucose logbook')]
# [('book', 'http://www.wikidata.org/entity/Q105339395'), ('bookname', 'school book author')]
# [('book', 'http://www.wikidata.org/entity/Q21976118'), ('bookname', 'Book of Mormon character')]
# [('book', 'http://www.wikidata.org/entity/Q3257185'), ('bookname', 'book-and-record set')]
# [('book', 'http://www.wikidata.org/entity/Q53731850'), ('bookname', 'individual copy of a book')]
# [('book', 'http://www.wikidata.org/entity/Q56560668'), ('bookname', 'book industry')]
# [('book', 'http://www.wikidata.org/entity/Q6017407'), ('bookname', 'independent bookstore')]
# 50

# %%
# aim: get the properties of 'banned book'
# result: we found the 'subclass of' property! Let's see if it is a subclass of a book class
queryString = """
SELECT DISTINCT ?p ?pn
WHERE {
   # bind something
   wd:Q65770793 ?p ?o .
   # ?p sc:name ?pn .
}
LIMIT 100
"""
print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P2347'), ('pn', 'YSO ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2354'), ('pn', 'has list')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pn', 'subclass of')]
# [('p', 'http://www.wikidata.org/prop/direct/P361'), ('pn', 'part of')]
# [('p', 'http://www.wikidata.org/prop/direct/P366'), ('pn', 'use')]
# [('p', 'http://www.wikidata.org/prop/direct/P5398'), ('pn', 'TDKIV term ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P910'), ('pn', "topic's main category")]
# 7

# %%
# aim: check the super class of 'banned book'
# result: we found the 'book' class! Let's check its properties
queryString = """
SELECT DISTINCT ?o ?on
WHERE {
   # bind something
   wd:Q65770793 wdt:P279 ?o .
   # ?o sc:name ?on .
}
LIMIT 100
"""
print("Results")
x=run_query(queryString)
# Out:
# Results
# [('o', 'http://www.wikidata.org/entity/Q571'), ('on', 'book')]
# [('o', 'http://www.wikidata.org/entity/Q66475652'), ('on', 'banned work')]
# 2

# %%
# aim: get the properties of the 'book' class
# result: we found the 'author' property! Now we can try to solve the task
queryString = """
SELECT DISTINCT ?p ?pn ?o ?on
WHERE {
   # bind something
   wd:Q571 ?p ?o .
   # ?o sc:name ?on .
   # ?p sc:name ?pn .
}
LIMIT 100
"""
print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P1151'), ('pn', "topic's main Wikimedia portal"), ('o', 'http://www.wikidata.org/entity/Q10880143'), ('on', 'Portal:Books')]
# [('p', 'http://www.wikidata.org/prop/direct/P1343'), ('pn', 'described by source'), ('o', 'http://www.wikidata.org/entity/Q106727050'), ('on', 'Metropolitan Museum of Art Tagging Vocabulary')]
# [('p', 'http://www.wikidata.org/prop/direct/P1343'), ('pn', 'described by source'), ('o', 'http://www.wikidata.org/entity/Q19180675'), ('on', 'Small Brockhaus and Efron Encyclopedic Dictionary')]
# [('p', 'http://www.wikidata.org/prop/direct/P1343'), ('pn', 'described by source'), ('o', 'http://www.wikidata.org/entity/Q602358'), ('on', 'Brockhaus and Efron Encyclopedic Dictionary')]
# [('p', 'http://www.wikidata.org/prop/direct/P1424'), ('pn', "topic's main template"), ('o', 'http://www.wikidata.org/entity/Q22835068'), ('on', 'Template:Infobox book 2')]
# [('p', 'http://www.wikidata.org/prop/direct/P1424'), ('pn', "topic's main template"), ('o', 'http://www.wikidata.org/entity/Q5858283'), ('on', 'Template:Infobox book')]
# [('p', 'http://www.wikidata.org/prop/direct/P1424'), ('pn', "topic's main template"), ('o', 'http://www.wikidata.org/entity/Q47482683'), ('on', 'Template:Books')]
# [('p', 'http://www.wikidata.org/prop/direct/P1552'), ('pn', 'has quality'), ('o', 'http://www.wikidata.org/entity/Q2985386'), ('on', 'editorial board')]
# [('p', 'http://www.wikidata.org/prop/direct/P1552'), ('pn', 'has quality'), ('o', 'http://www.wikidata.org/entity/Q2085381'), ('on', 'publisher')]
# [('p', 'http://www.wikidata.org/prop/direct/P1552'), ('pn', 'has quality'), ('o', 'http://www.wikidata.org/entity/Q998555'), ('on', 'book illustration')]
# [('p', 'http://www.wikidata.org/prop/direct/P1552'), ('pn', 'has quality'), ('o', 'http://www.wikidata.org/entity/Q34770'), ('on', 'language')]
# [('p', 'http://www.wikidata.org/prop/direct/P1552'), ('pn', 'has quality'), ('o', 'http://www.wikidata.org/entity/Q482980'), ('on', 'author')]
# [('p', 'http://www.wikidata.org/prop/direct/P1552'), ('pn', 'has quality'), ('o', 'http://www.wikidata.org/entity/Q1607826'), ('on', 'editor')]
# [('p', 'http://www.wikidata.org/prop/direct/P1552'), ('pn', 'has quality'), ('o', 'http://www.wikidata.org/entity/Q240471'), ('on', 'bookbinding')]
# [('p', 'http://www.wikidata.org/prop/direct/P1552'), ('pn', 'has quality'), ('o', 'http://www.wikidata.org/entity/Q1125338'), ('on', 'book cover')]
# [('p', 'http://www.wikidata.org/prop/direct/P1552'), ('pn', 'has quality'), ('o', 'http://www.wikidata.org/entity/Q33057'), ('on', 'International Standard Book Number')]
# [('p', 'http://www.wikidata.org/prop/direct/P1552'), ('pn', 'has quality'), ('o', 'http://www.wikidata.org/entity/Q1361758'), ('on', 'date of publication')]
# [('p', 'http://www.wikidata.org/prop/direct/P1552'), ('pn', 'has quality'), ('o', 'http://www.wikidata.org/entity/Q1238720'), ('on', 'volume')]
# [('p', 'http://www.wikidata.org/prop/direct/P1552'), ('pn', 'has quality'), ('o', 'http://www.wikidata.org/entity/Q783521'), ('on', 'title')]
# [('p', 'http://www.wikidata.org/prop/direct/P1552'), ('pn', 'has quality'), ('o', 'http://www.wikidata.org/entity/Q1361759'), ('on', 'place of publication')]
# [('p', 'http://www.wikidata.org/prop/direct/P1889'), ('pn', 'different from'), ('o', 'http://www.wikidata.org/entity/Q47461344'), ('on', 'written work')]
# [('p', 'http://www.wikidata.org/prop/direct/P1889'), ('pn', 'different from'), ('o', 'http://www.wikidata.org/entity/Q3331189'), ('on', 'version, edition, or translation')]
# [('p', 'http://www.wikidata.org/prop/direct/P1889'), ('pn', 'different from'), ('o', 'http://www.wikidata.org/entity/Q105763458'), ('on', 'volume')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pn', 'properties for this type'), ('o', 'http://www.wikidata.org/entity/P747'), ('on', 'has edition or translation')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pn', 'properties for this type'), ('o', 'http://www.wikidata.org/entity/P1476'), ('on', 'title')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pn', 'properties for this type'), ('o', 'http://www.wikidata.org/entity/P407'), ('on', 'language of work or name')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pn', 'properties for this type'), ('o', 'http://www.wikidata.org/entity/P50'), ('on', 'author')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pn', 'properties for this type'), ('o', 'http://www.wikidata.org/entity/P2969'), ('on', 'Goodreads version/edition ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pn', 'properties for this type'), ('o', 'http://www.wikidata.org/entity/P872'), ('on', 'printed by')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pn', 'properties for this type'), ('o', 'http://www.wikidata.org/entity/P3631'), ('on', 'Babelio work ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pn', 'properties for this type'), ('o', 'http://www.wikidata.org/entity/P1143'), ('on', 'BN (Argentine) editions')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pn', 'properties for this type'), ('o', 'http://www.wikidata.org/entity/P1823'), ('on', 'BAnQ work ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pn', 'properties for this type'), ('o', 'http://www.wikidata.org/entity/P2879'), ('on', 'Library of the National Congress of Argentina ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2184'), ('pn', 'history of topic'), ('o', 'http://www.wikidata.org/entity/Q15873402'), ('on', 'history of the book')]
# [('p', 'http://www.wikidata.org/prop/direct/P2354'), ('pn', 'has list'), ('o', 'http://www.wikidata.org/entity/Q5251635'), ('on', 'list of lists of books')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pn', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q49848'), ('on', 'document')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pn', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q2342494'), ('on', 'collectible')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pn', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q732577'), ('on', 'publication')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pn', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q47461344'), ('on', 'written work')]
# [('p', 'http://www.wikidata.org/prop/direct/P366'), ('pn', 'use'), ('o', 'http://www.wikidata.org/entity/Q3523102'), ('on', 'source of information')]
# [('p', 'http://www.wikidata.org/prop/direct/P366'), ('pn', 'use'), ('o', 'http://www.wikidata.org/entity/Q199657'), ('on', 'reading')]
# [('p', 'http://www.wikidata.org/prop/direct/P5008'), ('pn', 'on focus list of Wikimedia project'), ('o', 'http://www.wikidata.org/entity/Q5460604'), ('on', 'Wikipedia:Vital articles')]
# [('p', 'http://www.wikidata.org/prop/direct/P5125'), ('pn', 'Wikimedia outline'), ('o', 'http://www.wikidata.org/entity/Q7112569'), ('on', 'outline of books')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pn', 'has part'), ('o', 'http://www.wikidata.org/entity/Q234460'), ('on', 'text')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pn', 'has part'), ('o', 'http://www.wikidata.org/entity/Q1980247'), ('on', 'chapter')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pn', 'has part'), ('o', 'http://www.wikidata.org/entity/Q1069725'), ('on', 'page')]
# [('p', 'http://www.wikidata.org/prop/direct/P5869'), ('pn', 'model item'), ('o', 'http://www.wikidata.org/entity/Q191838'), ('on', 'The Count of Monte Cristo')]
# [('p', 'http://www.wikidata.org/prop/direct/P5869'), ('pn', 'model item'), ('o', 'http://www.wikidata.org/entity/Q428'), ('on', 'Quran')]
# [('p', 'http://www.wikidata.org/prop/direct/P5869'), ('pn', 'model item'), ('o', 'http://www.wikidata.org/entity/Q208002'), ('on', 'The Fellowship of the Ring')]
# [('p', 'http://www.wikidata.org/prop/direct/P5869'), ('pn', 'model item'), ('o', 'http://www.wikidata.org/entity/Q8265'), ('on', 'Dream of the Red Chamber')]
# [('p', 'http://www.wikidata.org/prop/direct/P6104'), ('pn', 'maintained by WikiProject'), ('o', 'http://www.wikidata.org/entity/Q8487081'), ('on', 'WikiProject Books')]
# [('p', 'http://www.wikidata.org/prop/direct/P910'), ('pn', "topic's main category"), ('o', 'http://www.wikidata.org/entity/Q5461161'), ('on', 'Category:Books')]
# 52

# %%
# aim: get the computer scientists who are author of something
# result: we actually retrieved some computer scientists. Now we have to make sure that what they have written is a book
queryString = """
SELECT DISTINCT ?personname ?book ?bookname
WHERE {
   # bind something
   # ?person wdt:P106 ?job ;
           sc:name ?personname .

   # ?book wdt:P50 ?person ;
         sc:name ?bookname .
   FILTER (?job = wd:Q82594)
}
LIMIT 5
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('personname', 'C Lee Giles'), ('book', 'http://www.wikidata.org/entity/Q21012586'), ('bookname', 'Persistence of Web references in scientific research')]
# [('personname', 'Steve Lawrence'), ('book', 'http://www.wikidata.org/entity/Q21012586'), ('bookname', 'Persistence of Web references in scientific research')]
# [('personname', 'C Lee Giles'), ('book', 'http://www.wikidata.org/entity/Q28140859'), ('bookname', 'Accessibility of information on the web')]
# [('personname', 'Steve Lawrence'), ('book', 'http://www.wikidata.org/entity/Q28140859'), ('bookname', 'Accessibility of information on the web')]
# [('personname', 'C Lee Giles'), ('book', 'http://www.wikidata.org/entity/Q61011726'), ('bookname', 'Digital libraries and autonomous citation indexing')]
# 5

# %%
# aim: get the types of literary work the computer scientists have done
# result: we actually retrieved some computer scientists. Now we have to make sure that what they have written is a book
queryString = """
SELECT DISTINCT ?instanceof ?instanceofname 
WHERE {
   # bind something
   # ?person wdt:P106 ?job ;
           sc:name ?personname .

   # ?book wdt:P50 ?person ;
         sc:name ?bookname ;
         wdt:P31 ?instanceof.
    # ?instanceof sc:name ?instanceofname
   FILTER (?job = wd:Q82594)
}
LIMIT 500
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('instanceof', 'http://www.wikidata.org/entity/Q815382'), ('instanceofname', 'meta-analysis')]
# [('instanceof', 'http://www.wikidata.org/entity/Q7318358'), ('instanceofname', 'review article')]
# [('instanceof', 'http://www.wikidata.org/entity/Q23011722'), ('instanceofname', 'TED talk')]
# [('instanceof', 'http://www.wikidata.org/entity/Q871232'), ('instanceofname', 'editorial')]
# [('instanceof', 'http://www.wikidata.org/entity/Q1668024'), ('instanceofname', 'service on internet')]
# [('instanceof', 'http://www.wikidata.org/entity/Q188860'), ('instanceofname', 'software library')]
# [('instanceof', 'http://www.wikidata.org/entity/Q189210'), ('instanceofname', 'web application')]
# [('instanceof', 'http://www.wikidata.org/entity/Q187685'), ('instanceofname', 'doctoral thesis')]
# [('instanceof', 'http://www.wikidata.org/entity/Q1348305'), ('instanceofname', 'erratum')]
# [('instanceof', 'http://www.wikidata.org/entity/Q23927052'), ('instanceofname', 'conference paper')]
# [('instanceof', 'http://www.wikidata.org/entity/Q1130645'), ('instanceofname', 'open-source software')]
# [('instanceof', 'http://www.wikidata.org/entity/Q13442814'), ('instanceofname', 'scholarly article')]
# [('instanceof', 'http://www.wikidata.org/entity/Q35127'), ('instanceofname', 'website')]
# [('instanceof', 'http://www.wikidata.org/entity/Q47461344'), ('instanceofname', 'written work')]
# [('instanceof', 'http://www.wikidata.org/entity/Q604733'), ('instanceofname', 'presentation')]
# [('instanceof', 'http://www.wikidata.org/entity/Q7725634'), ('instanceofname', 'literary work')]
# [('instanceof', 'http://www.wikidata.org/entity/Q341'), ('instanceofname', 'free software')]
# [('instanceof', 'http://www.wikidata.org/entity/Q3331189'), ('instanceofname', 'version, edition, or translation')]
# [('instanceof', 'http://www.wikidata.org/entity/Q1980247'), ('instanceofname', 'chapter')]
# [('instanceof', 'http://www.wikidata.org/entity/Q1810858'), ('instanceofname', 'blog software')]
# [('instanceof', 'http://www.wikidata.org/entity/Q40056'), ('instanceofname', 'computer program')]
# [('instanceof', 'http://www.wikidata.org/entity/Q571'), ('instanceofname', 'book')]
# [('instanceof', 'http://www.wikidata.org/entity/Q92438'), ('instanceofname', 'microblogging')]
# [('instanceof', 'http://www.wikidata.org/entity/Q3220391'), ('instanceofname', 'social networking service')]
# [('instanceof', 'http://www.wikidata.org/entity/Q877886'), ('instanceofname', 'compression software')]
# [('instanceof', 'http://www.wikidata.org/entity/Q192060'), ('instanceofname', 'knowledge management')]
# [('instanceof', 'http://www.wikidata.org/entity/Q1504425'), ('instanceofname', 'systematic review')]
# [('instanceof', 'http://www.wikidata.org/entity/Q3099732'), ('instanceofname', 'technical report')]
# [('instanceof', 'http://www.wikidata.org/entity/Q755673'), ('instanceofname', 'search algorithm')]
# [('instanceof', 'http://www.wikidata.org/entity/Q212971'), ('instanceofname', 'Request for Comments')]
# [('instanceof', 'http://www.wikidata.org/entity/Q2782326'), ('instanceofname', 'case report')]
# [('instanceof', 'http://www.wikidata.org/entity/Q580922'), ('instanceofname', 'preprint')]
# [('instanceof', 'http://www.wikidata.org/entity/Q56056731'), ('instanceofname', 'publishing platform')]
# [('instanceof', 'http://www.wikidata.org/entity/Q620615'), ('instanceofname', 'mobile app')]
# [('instanceof', 'http://www.wikidata.org/entity/Q1194970'), ('instanceofname', 'dot-com company')]
# [('instanceof', 'http://www.wikidata.org/entity/Q2594143'), ('instanceofname', 'word net')]
# [('instanceof', 'http://www.wikidata.org/entity/Q453843'), ('instanceofname', 'ontology editor')]
# [('instanceof', 'http://www.wikidata.org/entity/Q646754'), ('instanceofname', 'open letter')]
# [('instanceof', 'http://www.wikidata.org/entity/Q732577'), ('instanceofname', 'publication')]
# [('instanceof', 'http://www.wikidata.org/entity/Q1414362'), ('instanceofname', 'habilitation thesis')]
# [('instanceof', 'http://www.wikidata.org/entity/Q133492'), ('instanceofname', 'letter')]
# [('instanceof', 'http://www.wikidata.org/entity/Q17537576'), ('instanceofname', 'creative work')]
# [('instanceof', 'http://www.wikidata.org/entity/Q861911'), ('instanceofname', 'speech')]
# [('instanceof', 'http://www.wikidata.org/entity/Q18918145'), ('instanceofname', 'academic journal article')]
# [('instanceof', 'http://www.wikidata.org/entity/Q591041'), ('instanceofname', 'scientific publication')]
# [('instanceof', 'http://www.wikidata.org/entity/Q191067'), ('instanceofname', 'article')]
# [('instanceof', 'http://www.wikidata.org/entity/Q30849'), ('instanceofname', 'blog')]
# [('instanceof', 'http://www.wikidata.org/entity/Q1266946'), ('instanceofname', 'thesis')]
# [('instanceof', 'http://www.wikidata.org/entity/Q1143604'), ('instanceofname', 'proceedings')]
# [('instanceof', 'http://www.wikidata.org/entity/Q7316896'), ('instanceofname', 'retraction notice')]
# [('instanceof', 'http://www.wikidata.org/entity/Q21481766'), ('instanceofname', 'academic chapter')]
# [('instanceof', 'http://www.wikidata.org/entity/Q651270'), ('instanceofname', 'letter to the editor')]
# [('instanceof', 'http://www.wikidata.org/entity/Q5707594'), ('instanceofname', 'news article')]
# [('instanceof', 'http://www.wikidata.org/entity/Q11424'), ('instanceofname', 'film')]
# [('instanceof', 'http://www.wikidata.org/entity/Q15633582'), ('instanceofname', 'MediaWiki website')]
# [('instanceof', 'http://www.wikidata.org/entity/Q35760'), ('instanceofname', 'essay')]
# [('instanceof', 'http://www.wikidata.org/entity/Q7397'), ('instanceofname', 'software')]
# [('instanceof', 'http://www.wikidata.org/entity/Q1043076'), ('instanceofname', 'XML schema')]
# [('instanceof', 'http://www.wikidata.org/entity/Q20155966'), ('instanceofname', 'XML application')]
# [('instanceof', 'http://www.wikidata.org/entity/Q7889'), ('instanceofname', 'video game')]
# [('instanceof', 'http://www.wikidata.org/entity/Q207505'), ('instanceofname', 'lemma')]
# [('instanceof', 'http://www.wikidata.org/entity/Q23058953'), ('instanceofname', 'TEDx talk')]
# [('instanceof', 'http://www.wikidata.org/entity/Q1907875'), ('instanceofname', "master's thesis")]
# [('instanceof', 'http://www.wikidata.org/entity/Q193955'), ('instanceofname', 'hardback')]
# [('instanceof', 'http://www.wikidata.org/entity/Q783794'), ('instanceofname', 'company')]
# [('instanceof', 'http://www.wikidata.org/entity/Q11538'), ('instanceofname', 'mathematical proof')]
# [('instanceof', 'http://www.wikidata.org/entity/Q83790'), ('instanceofname', 'textbook')]
# [('instanceof', 'http://www.wikidata.org/entity/Q10870555'), ('instanceofname', 'report')]
# [('instanceof', 'http://www.wikidata.org/entity/Q65966993'), ('instanceofname', 'hypertext system')]
# [('instanceof', 'http://www.wikidata.org/entity/Q830340'), ('instanceofname', 'computer algebra system')]
# [('instanceof', 'http://www.wikidata.org/entity/Q193495'), ('instanceofname', 'monograph')]
# [('instanceof', 'http://www.wikidata.org/entity/Q26944781'), ('instanceofname', 'unpublished work')]
# [('instanceof', 'http://www.wikidata.org/entity/Q26700453'), ('instanceofname', 'fictional knowledge organization system')]
# [('instanceof', 'http://www.wikidata.org/entity/Q560361'), ('instanceofname', 'draft document')]
# [('instanceof', 'http://www.wikidata.org/entity/Q10885494'), ('instanceofname', 'scientific conference paper')]
# [('instanceof', 'http://www.wikidata.org/entity/Q2166013'), ('instanceofname', 'wiki hosting service')]
# [('instanceof', 'http://www.wikidata.org/entity/Q17009938'), ('instanceofname', 'data paper')]
# [('instanceof', 'http://www.wikidata.org/entity/Q97012313'), ('instanceofname', 'position statement')]
# [('instanceof', 'http://www.wikidata.org/entity/Q16599388'), ('instanceofname', 'SPID')]
# [('instanceof', 'http://www.wikidata.org/entity/Q213369'), ('instanceofname', 'webcomic')]
# [('instanceof', 'http://www.wikidata.org/entity/Q49084'), ('instanceofname', 'short story')]
# [('instanceof', 'http://www.wikidata.org/entity/Q725377'), ('instanceofname', 'graphic novel')]
# [('instanceof', 'http://www.wikidata.org/entity/Q15706459'), ('instanceofname', 'research article')]
# [('instanceof', 'http://www.wikidata.org/entity/Q59908'), ('instanceofname', 'opinion article')]
# [('instanceof', 'http://www.wikidata.org/entity/Q23058950'), ('instanceofname', 'TED Global talk')]
# [('instanceof', 'http://www.wikidata.org/entity/Q49848'), ('instanceofname', 'document')]
# [('instanceof', 'http://www.wikidata.org/entity/Q838795'), ('instanceofname', 'comic strip')]
# [('instanceof', 'http://www.wikidata.org/entity/Q192283'), ('instanceofname', 'news agency')]
# [('instanceof', 'http://www.wikidata.org/entity/Q15893266'), ('instanceofname', 'former entity')]
# [('instanceof', 'http://www.wikidata.org/entity/Q253623'), ('instanceofname', 'patent')]
# [('instanceof', 'http://www.wikidata.org/entity/Q309481'), ('instanceofname', 'obituary')]
# [('instanceof', 'http://www.wikidata.org/entity/Q2661442'), ('instanceofname', 'W3C Recommendation')]
# [('instanceof', 'http://www.wikidata.org/entity/Q277759'), ('instanceofname', 'book series')]
# [('instanceof', 'http://www.wikidata.org/entity/Q33120876'), ('instanceofname', 'Wikimedia content project')]
# [('instanceof', 'http://www.wikidata.org/entity/Q36509592'), ('instanceofname', 'wiki with script conversion')]
# [('instanceof', 'http://www.wikidata.org/entity/Q4182287'), ('instanceofname', 'search engine')]
# [('instanceof', 'http://www.wikidata.org/entity/Q5292'), ('instanceofname', 'encyclopedia')]
# [('instanceof', 'http://www.wikidata.org/entity/Q46337'), ('instanceofname', 'manifesto')]
# [('instanceof', 'http://www.wikidata.org/entity/Q5975031'), ('instanceofname', 'copyleft free software license')]
# [('instanceof', 'http://www.wikidata.org/entity/Q1228945'), ('instanceofname', 'working paper')]
# [('instanceof', 'http://www.wikidata.org/entity/Q324254'), ('instanceofname', 'ontology')]
# [('instanceof', 'http://www.wikidata.org/entity/Q58632367'), ('instanceofname', 'scholarly conference abstract')]
# [('instanceof', 'http://www.wikidata.org/entity/Q23622'), ('instanceofname', 'dictionary')]
# [('instanceof', 'http://www.wikidata.org/entity/Q14827288'), ('instanceofname', 'Wikimedia project')]
# [('instanceof', 'http://www.wikidata.org/entity/Q21191134'), ('instanceofname', 'comic strip series')]
# [('instanceof', 'http://www.wikidata.org/entity/Q1322187'), ('instanceofname', "April Fools' Day Request for Comments")]
# [('instanceof', 'http://www.wikidata.org/entity/Q17955'), ('instanceofname', 'criticism')]
# [('instanceof', 'http://www.wikidata.org/entity/Q1238720'), ('instanceofname', 'volume')]
# [('instanceof', 'http://www.wikidata.org/entity/Q947859'), ('instanceofname', 'research proposal')]
# [('instanceof', 'http://www.wikidata.org/entity/Q26202706'), ('instanceofname', 'Wikimania talk')]
# [('instanceof', 'http://www.wikidata.org/entity/Q30070590'), ('instanceofname', 'magazine article')]
# [('instanceof', 'http://www.wikidata.org/entity/Q23058816'), ('instanceofname', 'TED talk')]
# [('instanceof', 'http://www.wikidata.org/entity/Q29642950'), ('instanceofname', 'Python library')]
# [('instanceof', 'http://www.wikidata.org/entity/Q1004'), ('instanceofname', 'comics')]
# [('instanceof', 'http://www.wikidata.org/entity/Q3327521'), ('instanceofname', 'online dictionary')]
# [('instanceof', 'http://www.wikidata.org/entity/Q351507'), ('instanceofname', 'template processor')]
# [('instanceof', 'http://www.wikidata.org/entity/Q7433672'), ('instanceofname', 'scientific book')]
# [('instanceof', 'http://www.wikidata.org/entity/Q13433827'), ('instanceofname', 'encyclopedia article')]
# [('instanceof', 'http://www.wikidata.org/entity/Q30070439'), ('instanceofname', 'email')]
# [('instanceof', 'http://www.wikidata.org/entity/Q5152362'), ('instanceofname', 'commencement speech')]
# [('instanceof', 'http://www.wikidata.org/entity/Q2602337'), ('instanceofname', 'op-ed')]
# [('instanceof', 'http://www.wikidata.org/entity/Q603773'), ('instanceofname', 'lecture')]
# [('instanceof', 'http://www.wikidata.org/entity/Q107355827'), ('instanceofname', 'Wikimedia tool hosted on Toolforge')]
# [('instanceof', 'http://www.wikidata.org/entity/Q20937557'), ('instanceofname', 'series')]
# [('instanceof', 'http://www.wikidata.org/entity/Q998840'), ('instanceofname', 'word play')]
# [('instanceof', 'http://www.wikidata.org/entity/Q290378'), ('instanceofname', 'Internet Standard')]
# [('instanceof', 'http://www.wikidata.org/entity/Q2904257'), ('instanceofname', 'software development process')]
# [('instanceof', 'http://www.wikidata.org/entity/Q65581468'), ('instanceofname', 'linguistic example sentence')]
# [('instanceof', 'http://www.wikidata.org/entity/Q1711593'), ('instanceofname', 'edited volume')]
# [('instanceof', 'http://www.wikidata.org/entity/Q386724'), ('instanceofname', 'work')]
# [('instanceof', 'http://www.wikidata.org/entity/Q11024'), ('instanceofname', 'communication')]
# [('instanceof', 'http://www.wikidata.org/entity/Q168210'), ('instanceofname', 'Internet forum')]
# [('instanceof', 'http://www.wikidata.org/entity/Q20726407'), ('instanceofname', 'Wikidata tool')]
# [('instanceof', 'http://www.wikidata.org/entity/Q187931'), ('instanceofname', 'phrase')]
# [('instanceof', 'http://www.wikidata.org/entity/Q1550643'), ('instanceofname', 'principle')]
# [('instanceof', 'http://www.wikidata.org/entity/Q1279564'), ('instanceofname', 'short story collection')]
# [('instanceof', 'http://www.wikidata.org/entity/Q813912'), ('instanceofname', 'condition')]
# [('instanceof', 'http://www.wikidata.org/entity/Q1076547'), ('instanceofname', 'knowledge market')]
# [('instanceof', 'http://www.wikidata.org/entity/Q637866'), ('instanceofname', 'book review')]
# [('instanceof', 'http://www.wikidata.org/entity/Q16324495'), ('instanceofname', 'essay collection')]
# [('instanceof', 'http://www.wikidata.org/entity/Q57933693'), ('instanceofname', 'book edition')]
# [('instanceof', 'http://www.wikidata.org/entity/Q20540385'), ('instanceofname', 'non-fiction book')]
# [('instanceof', 'http://www.wikidata.org/entity/Q174989'), ('instanceofname', 'file system')]
# [('instanceof', 'http://www.wikidata.org/entity/Q1153191'), ('instanceofname', 'online newspaper')]
# [('instanceof', 'http://www.wikidata.org/entity/Q484652'), ('instanceofname', 'international organization')]
# [('instanceof', 'http://www.wikidata.org/entity/Q218616'), ('instanceofname', 'proprietary software')]
# [('instanceof', 'http://www.wikidata.org/entity/Q5375622'), ('instanceofname', 'encryption software')]
# [('instanceof', 'http://www.wikidata.org/entity/Q1344897'), ('instanceofname', 'whistleblower platform')]
# [('instanceof', 'http://www.wikidata.org/entity/Q29642842'), ('instanceofname', 'e-book reader software')]
# [('instanceof', 'http://www.wikidata.org/entity/Q178285'), ('instanceofname', 'freeware')]
# [('instanceof', 'http://www.wikidata.org/entity/Q30749496'), ('instanceofname', 'diploma thesis')]
# [('instanceof', 'http://www.wikidata.org/entity/Q3614994'), ('instanceofname', 'lexical analyzer generator')]
# [('instanceof', 'http://www.wikidata.org/entity/Q92998777'), ('instanceofname', 'opinion paper')]
# [('instanceof', 'http://www.wikidata.org/entity/Q3963243'), ('instanceofname', 'social news website')]
# [('instanceof', 'http://www.wikidata.org/entity/Q393351'), ('instanceofname', 'aggregator')]
# [('instanceof', 'http://www.wikidata.org/entity/Q178651'), ('instanceofname', 'interview')]
# [('instanceof', 'http://www.wikidata.org/entity/Q24634210'), ('instanceofname', 'podcast')]
# [('instanceof', 'http://www.wikidata.org/entity/Q23058952'), ('instanceofname', 'TED Women talk')]
# [('instanceof', 'http://www.wikidata.org/entity/Q1787111'), ('instanceofname', 'biographical dictionary')]
# [('instanceof', 'http://www.wikidata.org/entity/Q11266439'), ('instanceofname', 'Wikimedia template')]
# [('instanceof', 'http://www.wikidata.org/entity/Q19389637'), ('instanceofname', 'biographical article')]
# [('instanceof', 'http://www.wikidata.org/entity/Q58900620'), ('instanceofname', 'lecture notes')]
# [('instanceof', 'http://www.wikidata.org/entity/Q95977810'), ('instanceofname', 'Journal first Wikipedia-integrated dual publishing')]
# [('instanceof', 'http://www.wikidata.org/entity/Q47054'), ('instanceofname', 'riddle')]
# [('instanceof', 'http://www.wikidata.org/entity/Q57285129'), ('instanceofname', 'education company')]
# [('instanceof', 'http://www.wikidata.org/entity/Q1774662'), ('instanceofname', 'logic puzzle')]
# [('instanceof', 'http://www.wikidata.org/entity/Q19862851'), ('instanceofname', 'Massive online open course provider')]
# [('instanceof', 'http://www.wikidata.org/entity/Q132364'), ('instanceofname', 'communications protocol')]
# [('instanceof', 'http://www.wikidata.org/entity/Q220644'), ('instanceofname', 'service oriented architecture')]
# [('instanceof', 'http://www.wikidata.org/entity/Q1172284'), ('instanceofname', 'data set')]
# [('instanceof', 'http://www.wikidata.org/entity/Q55915575'), ('instanceofname', 'scholarly work')]
# [('instanceof', 'http://www.wikidata.org/entity/Q264238'), ('instanceofname', 'newsletter')]
# [('instanceof', 'http://www.wikidata.org/entity/Q59387148'), ('instanceofname', 'research report')]
# [('instanceof', 'http://www.wikidata.org/entity/Q12183006'), ('instanceofname', 'survey article')]
# [('instanceof', 'http://www.wikidata.org/entity/Q14406742'), ('instanceofname', 'comic book series')]
# [('instanceof', 'http://www.wikidata.org/entity/Q5398426'), ('instanceofname', 'television series')]
# [('instanceof', 'http://www.wikidata.org/entity/Q11826511'), ('instanceofname', 'scientific work')]
# [('instanceof', 'http://www.wikidata.org/entity/Q678345'), ('instanceofname', 'prequel')]
# [('instanceof', 'http://www.wikidata.org/entity/Q73539779'), ('instanceofname', 'R package')]
# [('instanceof', 'http://www.wikidata.org/entity/Q19269277'), ('instanceofname', 'first')]
# [('instanceof', 'http://www.wikidata.org/entity/Q56119332'), ('instanceofname', 'tweet')]
# [('instanceof', 'http://www.wikidata.org/entity/Q15292273'), ('instanceofname', 'watch blog')]
# [('instanceof', 'http://www.wikidata.org/entity/Q36279'), ('instanceofname', 'biography')]
# [('instanceof', 'http://www.wikidata.org/entity/Q207621'), ('instanceofname', 'software license')]
# [('instanceof', 'http://www.wikidata.org/entity/Q1437937'), ('instanceofname', 'permissive free software license')]
# [('instanceof', 'http://www.wikidata.org/entity/Q615699'), ('instanceofname', 'Internet encyclopedia')]
# [('instanceof', 'http://www.wikidata.org/entity/Q3943414'), ('instanceofname', 'free software license')]
# [('instanceof', 'http://www.wikidata.org/entity/Q15590336'), ('instanceofname', 'music streaming service')]
# [('instanceof', 'http://www.wikidata.org/entity/Q24577212'), ('instanceofname', 'citizen science project')]
# [('instanceof', 'http://www.wikidata.org/entity/Q19307174'), ('instanceofname', 'digital distribution platform')]
# [('instanceof', 'http://www.wikidata.org/entity/Q170584'), ('instanceofname', 'project')]
# [('instanceof', 'http://www.wikidata.org/entity/Q15836568'), ('instanceofname', 'computer network protocol')]
# [('instanceof', 'http://www.wikidata.org/entity/Q12139612'), ('instanceofname', 'list')]
# [('instanceof', 'http://www.wikidata.org/entity/Q1343205'), ('instanceofname', 'file hosting service')]
# [('instanceof', 'http://www.wikidata.org/entity/Q19541'), ('instanceofname', 'search engine')]
# [('instanceof', 'http://www.wikidata.org/entity/Q351764'), ('instanceofname', 'e-commerce payment system')]
# [('instanceof', 'http://www.wikidata.org/entity/Q131436'), ('instanceofname', 'board game')]
# [('instanceof', 'http://www.wikidata.org/entity/Q1643932'), ('instanceofname', 'tabletop role-playing game')]
# [('instanceof', 'http://www.wikidata.org/entity/Q241317'), ('instanceofname', 'computing platform')]
# [('instanceof', 'http://www.wikidata.org/entity/Q4830453'), ('instanceofname', 'business')]
# [('instanceof', 'http://www.wikidata.org/entity/Q166142'), ('instanceofname', 'application')]
# [('instanceof', 'http://www.wikidata.org/entity/Q506883'), ('instanceofname', 'free and open-source software')]
# [('instanceof', 'http://www.wikidata.org/entity/Q30059018'), ('instanceofname', 'operating system component')]
# [('instanceof', 'http://www.wikidata.org/entity/Q2021268'), ('instanceofname', 'BitTorrent tracker')]
# [('instanceof', 'http://www.wikidata.org/entity/Q89290172'), ('instanceofname', 'notorious market website')]
# [('instanceof', 'http://www.wikidata.org/entity/Q2079320'), ('instanceofname', 'OS-level virtualisation')]
# [('instanceof', 'http://www.wikidata.org/entity/Q2462003'), ('instanceofname', 'instant messaging client')]
# [('instanceof', 'http://www.wikidata.org/entity/Q4119870'), ('instanceofname', 'academic writing')]
# [('instanceof', 'http://www.wikidata.org/entity/Q87167'), ('instanceofname', 'manuscript')]
# [('instanceof', 'http://www.wikidata.org/entity/Q212805'), ('instanceofname', 'digital library')]
# [('instanceof', 'http://www.wikidata.org/entity/Q131093'), ('instanceofname', 'content management system')]
# [('instanceof', 'http://www.wikidata.org/entity/Q173212'), ('instanceofname', 'computer architecture')]
# [('instanceof', 'http://www.wikidata.org/entity/Q21127166'), ('instanceofname', 'Java software library')]
# [('instanceof', 'http://www.wikidata.org/entity/Q4117139'), ('instanceofname', 'biological database')]
# [('instanceof', 'http://www.wikidata.org/entity/Q59152282'), ('instanceofname', 'video streaming service')]
# [('instanceof', 'http://www.wikidata.org/entity/Q26921397'), ('instanceofname', 'password cracking software')]
# [('instanceof', 'http://www.wikidata.org/entity/Q868410'), ('instanceofname', 'graphics software')]
# [('instanceof', 'http://www.wikidata.org/entity/Q1727373'), ('instanceofname', 'lint')]
# [('instanceof', 'http://www.wikidata.org/entity/Q914359'), ('instanceofname', 'cloud storage')]
# [('instanceof', 'http://www.wikidata.org/entity/Q72610003'), ('instanceofname', 'Wikimedia type of file source')]
# [('instanceof', 'http://www.wikidata.org/entity/Q17928402'), ('instanceofname', 'blog post')]
# [('instanceof', 'http://www.wikidata.org/entity/Q66382991'), ('instanceofname', 'BiTtorrent search engine')]
# [('instanceof', 'http://www.wikidata.org/entity/Q25047642'), ('instanceofname', 'public domain equivalent license')]
# [('instanceof', 'http://www.wikidata.org/entity/Q91137337'), ('instanceofname', 'COVID-19 dataset')]
# [('instanceof', 'http://www.wikidata.org/entity/Q21682525'), ('instanceofname', 'Submission to NIST')]
# [('instanceof', 'http://www.wikidata.org/entity/Q14414034'), ('instanceofname', 'Potterfiction')]
# [('instanceof', 'http://www.wikidata.org/entity/Q604219'), ('instanceofname', 'photo-book')]
# [('instanceof', 'http://www.wikidata.org/entity/Q26225470'), ('instanceofname', 'alternate history novel')]
# [('instanceof', 'http://www.wikidata.org/entity/Q1077784'), ('instanceofname', 'programming tool')]
# [('instanceof', 'http://www.wikidata.org/entity/Q5633421'), ('instanceofname', 'scientific journal')]
# [('instanceof', 'http://www.wikidata.org/entity/Q4339810'), ('instanceofname', 'memory debugger')]
# [('instanceof', 'http://www.wikidata.org/entity/Q891055'), ('instanceofname', 'package management system')]
# [('instanceof', 'http://www.wikidata.org/entity/Q3814081'), ('instanceofname', 'app store')]
# [('instanceof', 'http://www.wikidata.org/entity/Q21130352'), ('instanceofname', 'group blog')]
# [('instanceof', 'http://www.wikidata.org/entity/Q464980'), ('instanceofname', 'exhibition')]
# [('instanceof', 'http://www.wikidata.org/entity/Q2916479'), ('instanceofname', 'shopping cart software')]
# 236

# %%
# aim: get the computer scientists who are author of at least an instance of 'book'
# result: we retrieved the computer scientists who have written at least a book
queryString = """
SELECT DISTINCT ?personname ?book ?bookname
WHERE {
   # bind something
   # ?person wdt:P106 ?job ;
           sc:name ?personname .

   # ?book wdt:P50 ?person ;
         sc:name ?bookname ;
         wdt:P31 wd:Q571 .
   FILTER (?job = wd:Q82594 )
}
LIMIT 5
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('personname', 'Eric S. Raymond'), ('book', 'http://www.wikidata.org/entity/Q467363'), ('bookname', 'The Cathedral and the Bazaar')]
# [('personname', 'Peter Dayan'), ('book', 'http://www.wikidata.org/entity/Q98835934'), ('bookname', 'Theoretical neuroscience: computational and mathematical modeling of neural systems')]
# [('personname', 'Cal Newport'), ('book', 'http://www.wikidata.org/entity/Q96653616'), ('bookname', "So Good They Can't Ignore You")]
# [('personname', 'Edward Tufte'), ('book', 'http://www.wikidata.org/entity/Q56741142'), ('bookname', 'The Visual Display of Quantitative Information')]
# [('personname', 'Yannis Tzitzikas'), ('book', 'http://www.wikidata.org/entity/Q105881996'), ('bookname', "Cinderella's Stick A Fairy Tale for Digital Preservation")]
# 5

# %%
# aim: get the computer scientists who are author of at least an instance of 'book' with the number of books written
# result: we retrieved the computer scientists who have written at least a book
queryString = """
SELECT DISTINCT ?person ?personname (COUNT(?book) AS ?numberOfBooks )
WHERE {
    {
       SELECT DISTINCT ?person ?personname ?book WHERE{
       
           # bind something
           # ?person wdt:P106 ?job ;
                   sc:name ?personname .

           # ?book wdt:P50 ?person ;
                 wdt:P31 wd:Q571 .
           FILTER (?job = wd:Q82594)
       }
    }
}GROUP BY ?person ?personname
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('person', 'http://www.wikidata.org/entity/Q2524992'), ('personname', 'Thomas H. Cormen'), ('numberOfBooks', '1')]
# [('person', 'http://www.wikidata.org/entity/Q104439764'), ('personname', 'Ole Tange'), ('numberOfBooks', '1')]
# [('person', 'http://www.wikidata.org/entity/Q1128109'), ('personname', 'Constanze Kurz'), ('numberOfBooks', '1')]
# [('person', 'http://www.wikidata.org/entity/Q3109900'), ('personname', 'Ralph Kimball'), ('numberOfBooks', '1')]
# [('person', 'http://www.wikidata.org/entity/Q77961153'), ('personname', 'Gayle Laakmann McDowell'), ('numberOfBooks', '1')]
# [('person', 'http://www.wikidata.org/entity/Q31040791'), ('personname', 'Michael Machtey'), ('numberOfBooks', '1')]
# [('person', 'http://www.wikidata.org/entity/Q93380549'), ('personname', 'Richard Szeliski'), ('numberOfBooks', '1')]
# [('person', 'http://www.wikidata.org/entity/Q719413'), ('personname', 'David Heinemeier Hansson'), ('numberOfBooks', '1')]
# [('person', 'http://www.wikidata.org/entity/Q3098629'), ('personname', 'Gary Vaynerchuk'), ('numberOfBooks', '1')]
# [('person', 'http://www.wikidata.org/entity/Q92832'), ('personname', 'Peter Norvig'), ('numberOfBooks', '1')]
# [('person', 'http://www.wikidata.org/entity/Q446862'), ('personname', 'David J. C. MacKay'), ('numberOfBooks', '1')]
# [('person', 'http://www.wikidata.org/entity/Q2024396'), ('personname', 'Clifford Stein'), ('numberOfBooks', '1')]
# [('person', 'http://www.wikidata.org/entity/Q16730319'), ('personname', 'John Cowan'), ('numberOfBooks', '1')]
# [('person', 'http://www.wikidata.org/entity/Q92636'), ('personname', 'John Ousterhout'), ('numberOfBooks', '1')]
# [('person', 'http://www.wikidata.org/entity/Q1194856'), ('personname', 'Alan Cooper'), ('numberOfBooks', '1')]
# [('person', 'http://www.wikidata.org/entity/Q188954'), ('personname', 'Eric S. Raymond'), ('numberOfBooks', '1')]
# [('person', 'http://www.wikidata.org/entity/Q16733303'), ('personname', 'Cal Newport'), ('numberOfBooks', '1')]
# [('person', 'http://www.wikidata.org/entity/Q384312'), ('personname', 'John Lions'), ('numberOfBooks', '1')]
# [('person', 'http://www.wikidata.org/entity/Q105887794'), ('personname', 'Yannis Marketakis'), ('numberOfBooks', '1')]
# [('person', 'http://www.wikidata.org/entity/Q23823587'), ('personname', 'Dan Gusfield'), ('numberOfBooks', '1')]
# [('person', 'http://www.wikidata.org/entity/Q93054'), ('personname', 'Evgeny Morozov'), ('numberOfBooks', '1')]
# [('person', 'http://www.wikidata.org/entity/Q58481435'), ('personname', 'Alberto Salarelli'), ('numberOfBooks', '1')]
# [('person', 'http://www.wikidata.org/entity/Q92741'), ('personname', 'Alonzo Church'), ('numberOfBooks', '1')]
# [('person', 'http://www.wikidata.org/entity/Q104154740'), ('personname', 'Panos Louridas'), ('numberOfBooks', '1')]
# [('person', 'http://www.wikidata.org/entity/Q30529466'), ('personname', 'Joris van der Hoeven'), ('numberOfBooks', '1')]
# [('person', 'http://www.wikidata.org/entity/Q2761378'), ('personname', 'Alvy Ray Smith'), ('numberOfBooks', '1')]
# [('person', 'http://www.wikidata.org/entity/Q19827680'), ('personname', 'Scott Cawthon'), ('numberOfBooks', '1')]
# [('person', 'http://www.wikidata.org/entity/Q93024'), ('personname', 'John Maeda'), ('numberOfBooks', '1')]
# [('person', 'http://www.wikidata.org/entity/Q3058394'), ('personname', 'Espen Aarseth'), ('numberOfBooks', '1')]
# [('person', 'http://www.wikidata.org/entity/Q5345024'), ('personname', 'Edward Reingold'), ('numberOfBooks', '1')]
# [('person', 'http://www.wikidata.org/entity/Q93043'), ('personname', 'Jonathan Bowen'), ('numberOfBooks', '2')]
# [('person', 'http://www.wikidata.org/entity/Q1181545'), ('personname', 'Debora Weber-Wulff'), ('numberOfBooks', '1')]
# [('person', 'http://www.wikidata.org/entity/Q1747747'), ('personname', 'Wolfgang Coy'), ('numberOfBooks', '1')]
# [('person', 'http://www.wikidata.org/entity/Q7173587'), ('personname', 'Peter Dayan'), ('numberOfBooks', '1')]
# [('person', 'http://www.wikidata.org/entity/Q64153792'), ('personname', 'Gabriel Weinberg'), ('numberOfBooks', '1')]
# [('person', 'http://www.wikidata.org/entity/Q12729229'), ('personname', 'Gheorghe Săsărman'), ('numberOfBooks', '1')]
# [('person', 'http://www.wikidata.org/entity/Q1293908'), ('personname', 'Edward Tufte'), ('numberOfBooks', '2')]
# [('person', 'http://www.wikidata.org/entity/Q578036'), ('personname', 'Ron Rivest'), ('numberOfBooks', '1')]
# [('person', 'http://www.wikidata.org/entity/Q92880'), ('personname', 'Gerard Salton'), ('numberOfBooks', '1')]
# [('person', 'http://www.wikidata.org/entity/Q93028'), ('personname', 'Charles E. Leiserson'), ('numberOfBooks', '1')]
# [('person', 'http://www.wikidata.org/entity/Q104919233'), ('personname', 'Gilles Blanc'), ('numberOfBooks', '1')]
# [('person', 'http://www.wikidata.org/entity/Q62874'), ('personname', 'John Edward Hopcroft'), ('numberOfBooks', '1')]
# [('person', 'http://www.wikidata.org/entity/Q64851946'), ('personname', 'Siegfried Handschuh'), ('numberOfBooks', '1')]
# [('person', 'http://www.wikidata.org/entity/Q92927'), ('personname', 'Noga Alon'), ('numberOfBooks', '2')]
# [('person', 'http://www.wikidata.org/entity/Q92824'), ('personname', 'Judea Pearl'), ('numberOfBooks', '1')]
# [('person', 'http://www.wikidata.org/entity/Q92629'), ('personname', 'Kenneth E. Iverson'), ('numberOfBooks', '1')]
# [('person', 'http://www.wikidata.org/entity/Q7615279'), ('personname', 'Steven Skiena'), ('numberOfBooks', '1')]
# [('person', 'http://www.wikidata.org/entity/Q29034984'), ('personname', 'Jean Gallier'), ('numberOfBooks', '1')]
# [('person', 'http://www.wikidata.org/entity/Q57231890'), ('personname', 'Michael Färber'), ('numberOfBooks', '1')]
# [('person', 'http://www.wikidata.org/entity/Q357918'), ('personname', 'László Lovász'), ('numberOfBooks', '1')]
# [('person', 'http://www.wikidata.org/entity/Q92908'), ('personname', 'Dave Raggett'), ('numberOfBooks', '1')]
# [('person', 'http://www.wikidata.org/entity/Q1239172'), ('personname', 'Martin Davis'), ('numberOfBooks', '1')]
# [('person', 'http://www.wikidata.org/entity/Q46633'), ('personname', 'Charles Babbage'), ('numberOfBooks', '1')]
# [('person', 'http://www.wikidata.org/entity/Q57226485'), ('personname', 'Yannis Tzitzikas'), ('numberOfBooks', '1')]
# [('person', 'http://www.wikidata.org/entity/Q18209412'), ('personname', 'Nachum Dershowitz'), ('numberOfBooks', '1')]
# [('person', 'http://www.wikidata.org/entity/Q7259'), ('personname', 'Ada Lovelace'), ('numberOfBooks', '1')]
# [('person', 'http://www.wikidata.org/entity/Q56651200'), ('personname', 'Dianna Xu'), ('numberOfBooks', '1')]
# [('person', 'http://www.wikidata.org/entity/Q92794'), ('personname', 'Jeffrey David Ullman'), ('numberOfBooks', '1')]
# [('person', 'http://www.wikidata.org/entity/Q6175114'), ('personname', 'Jeff Sutherland'), ('numberOfBooks', '1')]
# [('person', 'http://www.wikidata.org/entity/Q62898'), ('personname', 'Alfred Aho'), ('numberOfBooks', '1')]
# [('person', 'http://www.wikidata.org/entity/Q256657'), ('personname', 'Miha Mazzini'), ('numberOfBooks', '1')]
# [('person', 'http://www.wikidata.org/entity/Q315577'), ('personname', 'Hideo Kojima'), ('numberOfBooks', '2')]
# [('person', 'http://www.wikidata.org/entity/Q11817482'), ('personname', 'Piotr Gawrysiak'), ('numberOfBooks', '1')]
# [('person', 'http://www.wikidata.org/entity/Q441178'), ('personname', 'Raymond Smullyan'), ('numberOfBooks', '1')]
# 64

# %%
# aim: get the computer scientists who are author of at least 5 books
# result: no computer scientists has written at least 5 books 
queryString = """
SELECT DISTINCT ?person ?personname (COUNT(?book) AS ?numberOfBooks )
WHERE {
    {
       SELECT DISTINCT ?person ?personname ?book WHERE{
       
           # bind something
           # ?person wdt:P106 ?job ;
                   sc:name ?personname .

           # ?book wdt:P50 ?person ;
                 wdt:P31 wd:Q571 .
           FILTER (?job = wd:Q82594)
       }
    }
}GROUP BY ?person ?personname
HAVING (COUNT(?book)>=5)
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# Empty

# %%
# since the result set is empty we investigate more and we find other instances of resources that could be 'books'
# aim: get the computer scientists who are author of at least an instance of 'book','volume','scientific book','non-fiction book','textbook' and 'book series'
# result: we retrieved the computer scientists who have written at least a book
queryString = """
SELECT DISTINCT ?personname ?book ?bookname
WHERE {
   # bind something
   # ?person wdt:P106 ?job ;
           sc:name ?personname .

   # ?book wdt:P50 ?person ;
         sc:name ?bookname ;
         wdt:P31 ?booktype .
   FILTER (?job = wd:Q82594 && ?booktype IN (wd:Q571,wd:Q1238720,wd:Q7433672,wd:Q20540385,wd:Q83790,wd:Q277759))
}
LIMIT 5
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('personname', 'Alicja Corona Klenczon'), ('book', 'http://www.wikidata.org/entity/Q87123937'), ('bookname', 'Krzysztof Klenczon. Historia jednej znajomości')]
# [('personname', 'Ross J. Anderson'), ('book', 'http://www.wikidata.org/entity/Q47482099'), ('bookname', 'Security Engineering: A Guide to Building Dependable Distributed Systems')]
# [('personname', 'Stephen Emmott'), ('book', 'http://www.wikidata.org/entity/Q97127584'), ('bookname', 'Ten billions')]
# [('personname', 'Donald Knuth'), ('book', 'http://www.wikidata.org/entity/Q5157615'), ('bookname', 'Computers and Typesetting')]
# [('personname', 'Eric S. Raymond'), ('book', 'http://www.wikidata.org/entity/Q467363'), ('bookname', 'The Cathedral and the Bazaar')]
# 5

# %%
# aim: get the computer scientists who are author of at least an instance of 'book' with the number of books written
# result: we retrieved the computer scientists who have written at least a book
queryString = """
SELECT DISTINCT ?person ?personname (COUNT(?book) AS ?numberOfBooks )
WHERE {
    {
       SELECT DISTINCT ?person ?personname ?book WHERE{
       
           # bind something
           # ?person wdt:P106 ?job ;
                   sc:name ?personname .

           # ?book wdt:P50 ?person ;
                 wdt:P31 ?booktype .
           FILTER (?job = wd:Q82594 && ?booktype IN (wd:Q571,wd:Q1238720,wd:Q7433672,wd:Q20540385,wd:Q83790,wd:Q277759))
       }
    }
}GROUP BY ?person ?personname
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('person', 'http://www.wikidata.org/entity/Q17457'), ('personname', 'Donald Knuth'), ('numberOfBooks', '5')]
# [('person', 'http://www.wikidata.org/entity/Q2524992'), ('personname', 'Thomas H. Cormen'), ('numberOfBooks', '1')]
# [('person', 'http://www.wikidata.org/entity/Q104439764'), ('personname', 'Ole Tange'), ('numberOfBooks', '1')]
# [('person', 'http://www.wikidata.org/entity/Q1128109'), ('personname', 'Constanze Kurz'), ('numberOfBooks', '1')]
# [('person', 'http://www.wikidata.org/entity/Q3109900'), ('personname', 'Ralph Kimball'), ('numberOfBooks', '1')]
# [('person', 'http://www.wikidata.org/entity/Q6932746'), ('personname', 'Muhammad Suhail Zubairy'), ('numberOfBooks', '1')]
# [('person', 'http://www.wikidata.org/entity/Q105467898'), ('personname', 'Aitzol Astigarraga'), ('numberOfBooks', '2')]
# [('person', 'http://www.wikidata.org/entity/Q57654605'), ('personname', 'Agustin Arrieta Urtizberea'), ('numberOfBooks', '1')]
# [('person', 'http://www.wikidata.org/entity/Q77961153'), ('personname', 'Gayle Laakmann McDowell'), ('numberOfBooks', '1')]
# [('person', 'http://www.wikidata.org/entity/Q93380549'), ('personname', 'Richard Szeliski'), ('numberOfBooks', '1')]
# [('person', 'http://www.wikidata.org/entity/Q31040791'), ('personname', 'Michael Machtey'), ('numberOfBooks', '1')]
# [('person', 'http://www.wikidata.org/entity/Q719413'), ('personname', 'David Heinemeier Hansson'), ('numberOfBooks', '1')]
# [('person', 'http://www.wikidata.org/entity/Q3098629'), ('personname', 'Gary Vaynerchuk'), ('numberOfBooks', '1')]
# [('person', 'http://www.wikidata.org/entity/Q92832'), ('personname', 'Peter Norvig'), ('numberOfBooks', '2')]
# [('person', 'http://www.wikidata.org/entity/Q446862'), ('personname', 'David J. C. MacKay'), ('numberOfBooks', '1')]
# [('person', 'http://www.wikidata.org/entity/Q57083968'), ('personname', 'Xabier Arregi Iparragirre'), ('numberOfBooks', '2')]
# [('person', 'http://www.wikidata.org/entity/Q5277478'), ('personname', 'Dimitri Bertsekas'), ('numberOfBooks', '1')]
# [('person', 'http://www.wikidata.org/entity/Q2024396'), ('personname', 'Clifford Stein'), ('numberOfBooks', '1')]
# [('person', 'http://www.wikidata.org/entity/Q16730319'), ('personname', 'John Cowan'), ('numberOfBooks', '1')]
# [('person', 'http://www.wikidata.org/entity/Q92636'), ('personname', 'John Ousterhout'), ('numberOfBooks', '1')]
# [('person', 'http://www.wikidata.org/entity/Q1194856'), ('personname', 'Alan Cooper'), ('numberOfBooks', '1')]
# [('person', 'http://www.wikidata.org/entity/Q12253843'), ('personname', 'Arantza Diaz de Ilarraza Sanchez'), ('numberOfBooks', '3')]
# [('person', 'http://www.wikidata.org/entity/Q30942'), ('personname', 'Guido van Rossum'), ('numberOfBooks', '1')]
# [('person', 'http://www.wikidata.org/entity/Q2167581'), ('personname', 'Ross J. Anderson'), ('numberOfBooks', '1')]
# [('person', 'http://www.wikidata.org/entity/Q188954'), ('personname', 'Eric S. Raymond'), ('numberOfBooks', '1')]
# [('person', 'http://www.wikidata.org/entity/Q16733303'), ('personname', 'Cal Newport'), ('numberOfBooks', '1')]
# [('person', 'http://www.wikidata.org/entity/Q384312'), ('personname', 'John Lions'), ('numberOfBooks', '1')]
# [('person', 'http://www.wikidata.org/entity/Q23823587'), ('personname', 'Dan Gusfield'), ('numberOfBooks', '1')]
# [('person', 'http://www.wikidata.org/entity/Q105887794'), ('personname', 'Yannis Marketakis'), ('numberOfBooks', '1')]
# [('person', 'http://www.wikidata.org/entity/Q93054'), ('personname', 'Evgeny Morozov'), ('numberOfBooks', '1')]
# [('person', 'http://www.wikidata.org/entity/Q58481435'), ('personname', 'Alberto Salarelli'), ('numberOfBooks', '1')]
# [('person', 'http://www.wikidata.org/entity/Q92741'), ('personname', 'Alonzo Church'), ('numberOfBooks', '1')]
# [('person', 'http://www.wikidata.org/entity/Q30529466'), ('personname', 'Joris van der Hoeven'), ('numberOfBooks', '1')]
# [('person', 'http://www.wikidata.org/entity/Q104154740'), ('personname', 'Panos Louridas'), ('numberOfBooks', '1')]
# [('person', 'http://www.wikidata.org/entity/Q2761378'), ('personname', 'Alvy Ray Smith'), ('numberOfBooks', '1')]
# [('person', 'http://www.wikidata.org/entity/Q19827680'), ('personname', 'Scott Cawthon'), ('numberOfBooks', '1')]
# [('person', 'http://www.wikidata.org/entity/Q16517758'), ('personname', 'Iñaki Alegria'), ('numberOfBooks', '11')]
# [('person', 'http://www.wikidata.org/entity/Q3656334'), ('personname', 'Stuart J. Russell'), ('numberOfBooks', '1')]
# [('person', 'http://www.wikidata.org/entity/Q20492519'), ('personname', 'Olatz Arbelaitz'), ('numberOfBooks', '12')]
# [('person', 'http://www.wikidata.org/entity/Q105668925'), ('personname', 'Aitor Soroa'), ('numberOfBooks', '1')]
# [('person', 'http://www.wikidata.org/entity/Q93024'), ('personname', 'John Maeda'), ('numberOfBooks', '1')]
# [('person', 'http://www.wikidata.org/entity/Q3058394'), ('personname', 'Espen Aarseth'), ('numberOfBooks', '1')]
# [('person', 'http://www.wikidata.org/entity/Q5345024'), ('personname', 'Edward Reingold'), ('numberOfBooks', '1')]
# [('person', 'http://www.wikidata.org/entity/Q93043'), ('personname', 'Jonathan Bowen'), ('numberOfBooks', '2')]
# [('person', 'http://www.wikidata.org/entity/Q1181545'), ('personname', 'Debora Weber-Wulff'), ('numberOfBooks', '1')]
# [('person', 'http://www.wikidata.org/entity/Q1747747'), ('personname', 'Wolfgang Coy'), ('numberOfBooks', '1')]
# [('person', 'http://www.wikidata.org/entity/Q50177430'), ('personname', 'Kepa Sarasola Gabiola'), ('numberOfBooks', '7')]
# [('person', 'http://www.wikidata.org/entity/Q20492393'), ('personname', 'Montse Maritxalar Anglada'), ('numberOfBooks', '2')]
# [('person', 'http://www.wikidata.org/entity/Q7173587'), ('personname', 'Peter Dayan'), ('numberOfBooks', '1')]
# [('person', 'http://www.wikidata.org/entity/Q64153792'), ('personname', 'Gabriel Weinberg'), ('numberOfBooks', '1')]
# [('person', 'http://www.wikidata.org/entity/Q12729229'), ('personname', 'Gheorghe Săsărman'), ('numberOfBooks', '1')]
# [('person', 'http://www.wikidata.org/entity/Q105161273'), ('personname', 'Olatz Arregi Uriarte'), ('numberOfBooks', '1')]
# [('person', 'http://www.wikidata.org/entity/Q1293908'), ('personname', 'Edward Tufte'), ('numberOfBooks', '2')]
# [('person', 'http://www.wikidata.org/entity/Q92880'), ('personname', 'Gerard Salton'), ('numberOfBooks', '1')]
# [('person', 'http://www.wikidata.org/entity/Q104919233'), ('personname', 'Gilles Blanc'), ('numberOfBooks', '1')]
# [('person', 'http://www.wikidata.org/entity/Q578036'), ('personname', 'Ron Rivest'), ('numberOfBooks', '1')]
# [('person', 'http://www.wikidata.org/entity/Q93028'), ('personname', 'Charles E. Leiserson'), ('numberOfBooks', '1')]
# [('person', 'http://www.wikidata.org/entity/Q62874'), ('personname', 'John Edward Hopcroft'), ('numberOfBooks', '1')]
# [('person', 'http://www.wikidata.org/entity/Q64851946'), ('personname', 'Siegfried Handschuh'), ('numberOfBooks', '1')]
# [('person', 'http://www.wikidata.org/entity/Q92824'), ('personname', 'Judea Pearl'), ('numberOfBooks', '1')]
# [('person', 'http://www.wikidata.org/entity/Q92927'), ('personname', 'Noga Alon'), ('numberOfBooks', '2')]
# [('person', 'http://www.wikidata.org/entity/Q92629'), ('personname', 'Kenneth E. Iverson'), ('numberOfBooks', '1')]
# [('person', 'http://www.wikidata.org/entity/Q29034984'), ('personname', 'Jean Gallier'), ('numberOfBooks', '1')]
# [('person', 'http://www.wikidata.org/entity/Q7615279'), ('personname', 'Steven Skiena'), ('numberOfBooks', '1')]
# [('person', 'http://www.wikidata.org/entity/Q253960'), ('personname', 'Ravi Sethi'), ('numberOfBooks', '1')]
# [('person', 'http://www.wikidata.org/entity/Q86855976'), ('personname', 'Alicja Corona Klenczon'), ('numberOfBooks', '1')]
# [('person', 'http://www.wikidata.org/entity/Q57231890'), ('personname', 'Michael Färber'), ('numberOfBooks', '1')]
# [('person', 'http://www.wikidata.org/entity/Q357918'), ('personname', 'László Lovász'), ('numberOfBooks', '1')]
# [('person', 'http://www.wikidata.org/entity/Q92908'), ('personname', 'Dave Raggett'), ('numberOfBooks', '1')]
# [('person', 'http://www.wikidata.org/entity/Q1239172'), ('personname', 'Martin Davis'), ('numberOfBooks', '1')]
# [('person', 'http://www.wikidata.org/entity/Q20492609'), ('personname', 'Txelo Ruiz-Vazquez'), ('numberOfBooks', '2')]
# [('person', 'http://www.wikidata.org/entity/Q15964868'), ('personname', 'Elena Lazkano'), ('numberOfBooks', '1')]
# [('person', 'http://www.wikidata.org/entity/Q61996941'), ('personname', 'Izaskun Etxeberria Uztarroz'), ('numberOfBooks', '1')]
# [('person', 'http://www.wikidata.org/entity/Q13639575'), ('personname', 'Stephen Emmott'), ('numberOfBooks', '1')]
# [('person', 'http://www.wikidata.org/entity/Q46633'), ('personname', 'Charles Babbage'), ('numberOfBooks', '3')]
# [('person', 'http://www.wikidata.org/entity/Q57226485'), ('personname', 'Yannis Tzitzikas'), ('numberOfBooks', '1')]
# [('person', 'http://www.wikidata.org/entity/Q18209412'), ('personname', 'Nachum Dershowitz'), ('numberOfBooks', '1')]
# [('person', 'http://www.wikidata.org/entity/Q7259'), ('personname', 'Ada Lovelace'), ('numberOfBooks', '1')]
# [('person', 'http://www.wikidata.org/entity/Q56651200'), ('personname', 'Dianna Xu'), ('numberOfBooks', '1')]
# [('person', 'http://www.wikidata.org/entity/Q11763'), ('personname', 'Monica S. Lam'), ('numberOfBooks', '1')]
# [('person', 'http://www.wikidata.org/entity/Q6175114'), ('personname', 'Jeff Sutherland'), ('numberOfBooks', '1')]
# [('person', 'http://www.wikidata.org/entity/Q92794'), ('personname', 'Jeffrey David Ullman'), ('numberOfBooks', '2')]
# [('person', 'http://www.wikidata.org/entity/Q62898'), ('personname', 'Alfred Aho'), ('numberOfBooks', '2')]
# [('person', 'http://www.wikidata.org/entity/Q256657'), ('personname', 'Miha Mazzini'), ('numberOfBooks', '1')]
# [('person', 'http://www.wikidata.org/entity/Q315577'), ('personname', 'Hideo Kojima'), ('numberOfBooks', '2')]
# [('person', 'http://www.wikidata.org/entity/Q11817482'), ('personname', 'Piotr Gawrysiak'), ('numberOfBooks', '1')]
# [('person', 'http://www.wikidata.org/entity/Q441178'), ('personname', 'Raymond Smullyan'), ('numberOfBooks', '1')]
# [('person', 'http://www.wikidata.org/entity/Q107856074'), ('personname', 'Javier Alvez Gimenez'), ('numberOfBooks', '1')]
# [('person', 'http://www.wikidata.org/entity/Q63845182'), ('personname', 'Olatz Perez-de-Viñaspre'), ('numberOfBooks', '1')]
# 89

# %% [markdown]
# Final query for this task

# %%
# aim: get the computer scientists who are author of at least 5 books
# result: no computer scientists has written at least 5 books 
queryString = """
SELECT DISTINCT ?person ?personname (COUNT(?book) AS ?numberOfBooks )
WHERE {
    {
       SELECT DISTINCT ?person ?personname ?book WHERE{
       
           # bind something
           # ?person wdt:P106 ?job ;
                   sc:name ?personname .

           # ?book wdt:P50 ?person ;
                 wdt:P31 ?booktype .
           FILTER (?job = wd:Q82594 && ?booktype IN (wd:Q571,wd:Q1238720,wd:Q7433672,wd:Q20540385,wd:Q83790,wd:Q277759))
       }
    }
}GROUP BY ?person ?personname
HAVING (COUNT(?book)>=5)
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('person', 'http://www.wikidata.org/entity/Q17457'), ('personname', 'Donald Knuth'), ('numberOfBooks', '5')]
# [('person', 'http://www.wikidata.org/entity/Q16517758'), ('personname', 'Iñaki Alegria'), ('numberOfBooks', '11')]
# [('person', 'http://www.wikidata.org/entity/Q20492519'), ('personname', 'Olatz Arbelaitz'), ('numberOfBooks', '12')]
# [('person', 'http://www.wikidata.org/entity/Q50177430'), ('personname', 'Kepa Sarasola Gabiola'), ('numberOfBooks', '7')]
# 4

# %%
#
#
# OBSERVATION: the first queries that are used to get the class 'book' can be expensive even though the LIMIT has a low value. Therefore here we try to provide an alternative way
# that could have been used to get the class book.
# aim: from the task before we got all the persons that are computer scientists and university teachers. Some of them must have written something so they should have some kind of
#      author property connected to them. Therefore we want to list all the distinct properties to find an 'author' property.

# result: we found the 'author' property. Now we just have to find if it connects them to books.
queryString = """
SELECT DISTINCT ?p ?pname
WHERE {
   # bind something
   # ?person wdt:P106 wd:Q82594 ;
           wdt:P106 wd:Q1622272 .
   
   # ?s ?p ?person.
   # ?p sc:name ?pname .
           
   FILTER REGEX (?pname, "author","i").
}
LIMIT 50
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P50'), ('pname', 'author')]
# [('p', 'http://www.wikidata.org/prop/direct/P2679'), ('pname', 'author of foreword')]
# [('p', 'http://www.wikidata.org/prop/direct/P2680'), ('pname', 'author of afterword')]
# 3

# %%
# aim: get all the resources for which computer scientists are author containing the word 'book'
# result: we retrieved some results but we are not sure that all of them are books so we need to find only the ones that are 'instanceOf' a 'book' class

queryString = """
SELECT DISTINCT ?s ?sname
WHERE {
   # bind something
   # ?person wdt:P106 wd:Q82594 ;
           wdt:P106 wd:Q1622272 .
   
   # ?s wdt:P50 ?person.
   # ?s sc:name ?sname .
           
   FILTER REGEX (?sname, "book","i").
}
LIMIT 200
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('s', 'http://www.wikidata.org/entity/Q56385312'), ('sname', 'Book Review: Extremal graph theory')]
# [('s', 'http://www.wikidata.org/entity/Q56387458'), ('sname', 'Book Review: Winning ways for your mathematical plays')]
# [('s', 'http://www.wikidata.org/entity/Q55970196'), ('sname', 'Book Review: Introduction to Logic and to the Methodology of Deductive Sciences')]
# [('s', 'http://www.wikidata.org/entity/Q50842887'), ('sname', "The ABC Programmer's Handbook")]
# [('s', 'http://www.wikidata.org/entity/Q57066571'), ('sname', 'Making friends and communicating on Facebook: Implications for the access to social capital')]
# [('s', 'http://www.wikidata.org/entity/Q57066567'), ('sname', 'Corrigendum to “Making friends and communicating on Facebook: Implications for social capital” [Soc. Netw. (2014) 29–41]')]
# [('s', 'http://www.wikidata.org/entity/Q57066614'), ('sname', 'Bookmaker consensus and agreement for the UEFA Champions League 2008/2009')]
# [('s', 'http://www.wikidata.org/entity/Q19595428'), ('sname', 'The TeXbook')]
# [('s', 'http://www.wikidata.org/entity/Q56068330'), ('sname', 'Book Review: A System of Logistic')]
# [('s', 'http://www.wikidata.org/entity/Q56093791'), ('sname', 'Book Review: Foundations of Logic and Mathematics')]
# [('s', 'http://www.wikidata.org/entity/Q56475193'), ('sname', 'Book Review: Mathematische Grundlagenforschung. Intuitionismus. Beweistheorie')]
# [('s', 'http://www.wikidata.org/entity/Q105032182'), ('sname', 'Numerical Recipes in C++: The Art of Scientific Computing (2nd edn) 1 Numerical Recipes Example Book (C++) (2nd edn) 2 Numerical Recipes Multi-Language Code CD ROM with LINUX or UNIX Single-Screen License Revised Version 3')]
# [('s', 'http://www.wikidata.org/entity/Q105032011'), ('sname', 'Books: That Perfect Algorithm for Any Occasion [two book reviews]')]
# [('s', 'http://www.wikidata.org/entity/Q57266557'), ('sname', 'Abstract 60: The MedBook network for cancer precision medical care')]
# [('s', 'http://www.wikidata.org/entity/Q60325839'), ('sname', 'Opportunities for and limitations of the Book Citation Index')]
# [('s', 'http://www.wikidata.org/entity/Q58489822'), ('sname', 'Handbook for the GREAT08 Challenge: An image analysis competition for cosmological lensing')]
# [('s', 'http://www.wikidata.org/entity/Q57340956'), ('sname', 'Gravitational Lensing Accuracy Testing 2010 (GREAT10) Challenge Handbook')]
# [('s', 'http://www.wikidata.org/entity/Q98199430'), ('sname', 'The Book of Why')]
# [('s', 'http://www.wikidata.org/entity/Q33810851'), ('sname', 'The book of Hebb.')]
# [('s', 'http://www.wikidata.org/entity/Q59820785'), ('sname', 'Realistic electronic books')]
# [('s', 'http://www.wikidata.org/entity/Q62502988'), ('sname', "The International Children's Digital Library: viewing digital books online")]
# [('s', 'http://www.wikidata.org/entity/Q59549979'), ('sname', 'Creating and Reading Realistic Electronic Books')]
# [('s', 'http://www.wikidata.org/entity/Q62502822'), ('sname', 'Designing the reading experience for scanned multi-lingual picture books on mobile phones')]
# [('s', 'http://www.wikidata.org/entity/Q59549984'), ('sname', 'Searching in a Book')]
# [('s', 'http://www.wikidata.org/entity/Q62502837'), ('sname', 'Preface: When a Book Came to be')]
# [('s', 'http://www.wikidata.org/entity/Q62502830'), ('sname', 'How People Read Books Online: Mining and Visualizing Web Logs for Use Information')]
# [('s', 'http://www.wikidata.org/entity/Q62502832'), ('sname', 'Locating text in scanned books')]
# [('s', 'http://www.wikidata.org/entity/Q62502858'), ('sname', 'Readability of scanned books in digital libraries')]
# [('s', 'http://www.wikidata.org/entity/Q59550007'), ('sname', 'Lightweight realistic books')]
# [('s', 'http://www.wikidata.org/entity/Q59820789'), ('sname', "A Bookmaker's Workbench")]
# [('s', 'http://www.wikidata.org/entity/Q21181449'), ('sname', 'What Is the Name of This Book?')]
# [('s', 'http://www.wikidata.org/entity/Q3414078'), ('sname', 'What is the name of this book?')]
# [('s', 'http://www.wikidata.org/entity/Q57400679'), ('sname', 'Domain Module Building From Textbooks: Integrating Automatic Exercise Generation')]
# [('s', 'http://www.wikidata.org/entity/Q56604878'), ('sname', 'Falling asleep with Angry Birds, Facebook and Kindle')]
# [('s', 'http://www.wikidata.org/entity/Q56601919'), ('sname', 'Book Review: Mathematical experiments on the computer')]
# [('s', 'http://www.wikidata.org/entity/Q56020569'), ('sname', 'Can Government Go Bankrupt? By Rose Richard and Peters Guy. (New York: Basic Books, 1978. Pp. xv + 283. $12.50.)')]
# [('s', 'http://www.wikidata.org/entity/Q59570554'), ('sname', 'Designer modeling for Sentient Sketchbook')]
# [('s', 'http://www.wikidata.org/entity/Q29037520'), ('sname', 'Social capital on facebook')]
# 38

# %%
# aim: get all the resources for which computer scientists are author containing the word 'book'
# result: we retrieved the 'book' class in a more efficient way

queryString = """
SELECT DISTINCT ?artworkclass ?name
WHERE {
   # bind something
   # ?person wdt:P106 wd:Q82594 ;
           wdt:P106 wd:Q1622272 .
   
   # ?s wdt:P50 ?person;
       wdt:P31 ?artworkclass.
   # ?artworkclass sc:name ?name .
           
   FILTER REGEX (?name, "book","i").
}
LIMIT 200
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('artworkclass', 'http://www.wikidata.org/entity/Q571'), ('name', 'book')]
# [('artworkclass', 'http://www.wikidata.org/entity/Q83790'), ('name', 'textbook')]
# [('artworkclass', 'http://www.wikidata.org/entity/Q277759'), ('name', 'book series')]
# [('artworkclass', 'http://www.wikidata.org/entity/Q7433672'), ('name', 'scientific book')]
# [('artworkclass', 'http://www.wikidata.org/entity/Q20540385'), ('name', 'non-fiction book')]
# [('artworkclass', 'http://www.wikidata.org/entity/Q57933693'), ('name', 'book edition')]
# [('artworkclass', 'http://www.wikidata.org/entity/Q637866'), ('name', 'book review')]
# 7

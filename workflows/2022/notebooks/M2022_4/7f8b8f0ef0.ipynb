# %% [markdown]
# # General instructions
#
# The goal of the project is to materialize a set of **exploratory workloads** over a real-world, large-scale,  open-domain KG: [WikiData](https://www.wikidata.org/wiki/Wikidata:Main_Page)
#
# An exploratory workload  is composed by a set of queries, where each query is related to the information obtained previously.
#
# An exploratory workload starts with a usually vague, open ended question, and does not assume the person issuing the workload has a clear understanding of the data contained in the target database or its structure.
#
# Remeber that:
#
# 1. All the queries must run in the python notebook
# 2. You can use classes and properties only if you find them via a SPARQL query that must be present in the notebook
# 3. You do not delete useless queries. Keep everything that is synthatically valid
#
# ```
# ?p <http://schema.org/name> ?name .
# ```
#
#     is the BGP returning a human-readable name of a property or a class in Wikidata.

# %%
## SETUP used later

from SPARQLWrapper import SPARQLWrapper, JSON


prefixString = """
##-7f8b8f0ef0-##
PREFIX wd: <http://www.wikidata.org/entity/> 
PREFIX wdt: <http://www.wikidata.org/prop/direct/> 
PREFIX sc: <http://schema.org/>
"""

# select and construct queries
def run_query(queryString,verbose = True):
    to_run = prefixString + "\n" + queryString

    sparql = SPARQLWrapper("http://a256-gc1-03.srv.aau.dk:5820/sparql")
    sparql.setTimeout(300)
    sparql.setReturnFormat(JSON)
    sparql.setQuery(to_run)

    try :
        results = sparql.query()
        json_results = results.convert()
        if len(json_results['results']['bindings'])==0:
            print("Empty")
            return []
        array = []
        for bindings in json_results['results']['bindings']:
            app =  [ (var, value['value'])  for var, value in bindings.items() ] 
            if verbose:
                print( app)
            array.append(app)
        if verbose:
            print(len(array))
        return array

    except Exception as e :
        print("The operation failed", e)
    
# ASk queries
def run_ask_query(queryString):
    to_run = prefixString + "\n" + queryString

    sparql = SPARQLWrapper("http://a256-gc1-03.srv.aau.dk:5820/sparql")
    sparql.setTimeout(300)
    sparql.setReturnFormat(JSON)
    sparql.setQuery(to_run)

    try :
        return sparql.query().convert()

    except Exception as e :
        print("The operation failed", e)

# %% [markdown]
# # Movie Workflow Series ("Tv series HIMYM explorative search")
#
#
# Consider the following exploratory scenario:
#
#
# > we are interested in the TV series "How I met your mother" and we want to investigate the main aspects related to the actors and directors involved in the production, know the numerber of seasons and check what are the episodes which got the higher success/impact.
#
#
# ## Useful URIs for the current workflow
# The following are given:
#
# | IRI           | Description   | Role      |
# | -----------   | -----------   |-----------|
# | `wdt:P1647`   | subproperty   | predicate |
# | `wdt:P31`     | instance of   | predicate |
# | `wdt:P106`    | profession    | predicate |
# | `wdt:P279`    | subclass      | predicate |
# | `wdt:P4969`    | derivative work      | predicate |
# | `wd:Q147235` | How I met your mother        | node |
# | `wd:Q23831` | The Office (US)        | node |
#
#
#
# Also consider
#
# ```
# wd:Q23831 ?p ?obj .
# ```
#
# is the BGP to retrieve all **properties of The Office (US)**
#
# Please consider that when you return a resource, you should return the IRI and the label of the resource. In particular, when the task require you to identify a BGP the result set must always be a list of couples IRI - label.
#
# The workload should
#
# 1. Identify the BGP for tv series
#
# 2. Return the number of seasons and episodes per season of the tv series (the result set must be triples of season IRI, label and #episodes).
#
# 3. Get the number of episodes in which the cast members played a role. Who are the most present actors? (the result set must be a list of triples actor/actress IRI, label and #episodes)
#
# 4. Check who is the actor who acted in more films while working on "How I met your mother" (the result set must be a list of triples actor/actress IRI, label and #films).
#
# 5. Compare HIMYM with the tv series "The Office (US)" in terms of number of seasons, episods and cast members (the result set must be two elements -one for each tv series- of tv series IRI, label, #seasons, #episodes and #cast members).
#
# 6. Return how many of the actors who are members of the cast of the tv series have [Kavin Bacon number](https://en.wikipedia.org/wiki/Six_Degrees_of_Kevin_Bacon#:~:text=Kevin%20Bacon%20himself%20has%20a,Bacon%20number%20is%20N%2B1.) equal to 2 (the result set must be a list of couples actor/actress IRI and label).
#
# 7. Consider the actors who are members of the cast of HIMYM. Amongst the tv series which these actors acted return only those which received more than 2 awards (the result set must be triples of tv series IRI, label, #awards won).

# %% [markdown]
# ## Task 1
# Identify the BGP for tv series

# %%
# query example
queryString = """
SELECT DISTINCT ?p ?name
WHERE {
   # bind something
   wd:Q23831 ?p ?obj .
   # get the label
   # ?p sc:name ?name.
}
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P1113'), ('name', 'number of episodes')]
# [('p', 'http://www.wikidata.org/prop/direct/P1258'), ('name', 'Rotten Tomatoes ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1267'), ('name', 'AlloCiné series ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P136'), ('name', 'genre')]
# [('p', 'http://www.wikidata.org/prop/direct/P1417'), ('name', 'Encyclopædia Britannica Online ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P144'), ('name', 'based on')]
# [('p', 'http://www.wikidata.org/prop/direct/P1476'), ('name', 'title')]
# [('p', 'http://www.wikidata.org/prop/direct/P154'), ('name', 'logo image')]
# [('p', 'http://www.wikidata.org/prop/direct/P1552'), ('name', 'has quality')]
# [('p', 'http://www.wikidata.org/prop/direct/P1562'), ('name', 'AllMovie title ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P161'), ('name', 'cast member')]
# [('p', 'http://www.wikidata.org/prop/direct/P170'), ('name', 'creator')]
# [('p', 'http://www.wikidata.org/prop/direct/P1712'), ('name', 'Metacritic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P18'), ('name', 'image')]
# [('p', 'http://www.wikidata.org/prop/direct/P1811'), ('name', 'list of episodes')]
# [('p', 'http://www.wikidata.org/prop/direct/P1874'), ('name', 'Netflix ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1889'), ('name', 'different from')]
# [('p', 'http://www.wikidata.org/prop/direct/P2002'), ('name', 'Twitter username')]
# [('p', 'http://www.wikidata.org/prop/direct/P2061'), ('name', 'aspect ratio')]
# [('p', 'http://www.wikidata.org/prop/direct/P214'), ('name', 'VIAF ID')]
# 20

# %%
#P136 genre
queryString = """
SELECT DISTINCT ?sName ?oName
WHERE {
   # ?s wdt:P136 ?o .
   # ?s sc:name ?sName.
   # ?o sc:name ?oName.
}
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('sName', 'Harpist of Keros'), ('oName', 'Cycladic art')]
# [('sName', 'Ayinde Barrister'), ('oName', 'fuji music')]
# [('sName', 'Crying for No Reason'), ('oName', 'breakstep')]
# [('sName', 'Chapliniana'), ('oName', 'ballet film')]
# [('sName', 'Scribblenauts Unmasked: A DC Comics Adventure'), ('oName', 'emergent gameplay')]
# [('sName', 'Ajin'), ('oName', 'supernatural anime and manga')]
# [('sName', 'Rygar'), ('oName', 'spacesynth')]
# [('sName', 'Amoeba Cleansing Syndrome'), ('oName', 'progressive soul')]
# [('sName', 'Love Steaks'), ('oName', 'Mumblecore')]
# [('sName', 'Nimrod Borenstein'), ('oName', 'ballet')]
# [('sName', 'Shakey Jake Harris'), ('oName', 'Chicago blues')]
# [('sName', 'Da Funk'), ('oName', 'acid house')]
# [('sName', 'Lee Kwang-ki'), ('oName', 'trot')]
# [('sName', 'Seo In-ah'), ('oName', 'trot')]
# [('sName', 'Kim Ji-ae'), ('oName', 'trot')]
# [('sName', 'Oöphoi'), ('oName', 'dark ambient')]
# [('sName', 'Necrophagist'), ('oName', 'technical death metal')]
# [('sName', 'Rivers of Nihil'), ('oName', 'technical death metal')]
# [('sName', 'Aura Hiemis'), ('oName', 'death-doom')]
# [('sName', 'Rich Homie Quan'), ('oName', 'trap music')]
# 20

# %%
#P1811 list of episodes

queryString = """
SELECT DISTINCT ?s ?sName ?oName
WHERE {
   # ?s wdt:P1811 ?o .
   # ?s sc:name ?sName.
   # ?o sc:name ?oName.
}
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('s', 'http://www.wikidata.org/entity/Q15594658'), ('sName', 'Cutthroat Kitchen'), ('oName', 'list of Cutthroat Kitchen episodes')]
# [('s', 'http://www.wikidata.org/entity/Q15731300'), ('sName', 'Power Rangers Dino Charge'), ('oName', 'List of Power Rangers Dino Charge episodes')]
# [('s', 'http://www.wikidata.org/entity/Q16039926'), ('sName', 'Garo: Makai no Hana'), ('oName', 'list of Garo: Makai no Hana episodes')]
# [('s', 'http://www.wikidata.org/entity/Q13479326'), ('sName', 'RWBY'), ('oName', 'list of RWBY episodes')]
# [('s', 'http://www.wikidata.org/entity/Q60740094'), ('sName', 'Danganronpa: The Animation'), ('oName', 'list of Danganronpa: The Animation episodes')]
# [('s', 'http://www.wikidata.org/entity/Q2757796'), ('sName', 'Nisekoi'), ('oName', 'list of Nisekoi episodes')]
# [('s', 'http://www.wikidata.org/entity/Q2555936'), ('sName', 'Meine Liebe'), ('oName', 'list of Meine Liebe episodes')]
# [('s', 'http://www.wikidata.org/entity/Q15303732'), ('sName', 'The Tonight Show Starring Jimmy Fallon'), ('oName', 'list of The Tonight Show Starring Jimmy Fallon episodes')]
# [('s', 'http://www.wikidata.org/entity/Q17034872'), ('sName', 'Sirens'), ('oName', 'list of Sirens (2014 TV series) episodes')]
# [('s', 'http://www.wikidata.org/entity/Q17010736'), ('sName', "RuPaul's Drag U"), ('oName', "list of RuPaul's Drag U episodes")]
# [('s', 'http://www.wikidata.org/entity/Q17053914'), ('sName', 'Your Pretty Face Is Going to Hell'), ('oName', 'list of Your Pretty Face Is Going to Hell episodes')]
# [('s', 'http://www.wikidata.org/entity/Q17501992'), ('sName', 'Dora and Friends: Into the City!'), ('oName', 'list of Dora and Friends: Into the City! episodes')]
# [('s', 'http://www.wikidata.org/entity/Q16138249'), ('sName', 'Sailor Moon Crystal'), ('oName', 'list of Sailor Moon Crystal episodes')]
# [('s', 'http://www.wikidata.org/entity/Q17635847'), ('sName', 'K.C. Undercover'), ('oName', 'list of K.C. Undercover episodes')]
# [('s', 'http://www.wikidata.org/entity/Q18151386'), ('sName', 'Kirby Buckets'), ('oName', 'list of Kirby Buckets episodes')]
# [('s', 'http://www.wikidata.org/entity/Q18127230'), ('sName', 'Life is Beautiful'), ('oName', 'list of Life Is Beautiful episodes')]
# [('s', 'http://www.wikidata.org/entity/Q18151589'), ('sName', 'The Late Late Show with James Corden'), ('oName', 'list of The Late Late Show with James Corden episodes')]
# [('s', 'http://www.wikidata.org/entity/Q318649'), ('sName', 'Ghost Whisperer'), ('oName', 'list of Ghost Whisperer episodes')]
# [('s', 'http://www.wikidata.org/entity/Q19349423'), ('sName', 'King of Mask Singer'), ('oName', 'list of King of Mask Singer episodes')]
# [('s', 'http://www.wikidata.org/entity/Q3533342'), ('sName', 'W.I.T.C.H.'), ('oName', 'list of W.I.T.C.H. episodes')]
# 20

# %%
#Q15594658 Cutthroat Kitchen
queryString = """
SELECT DISTINCT ?p ?pName ?o ?oName
WHERE {
   wd:Q15594658 ?p ?o .
   # ?p sc:name ?pName.
   # ?o sc:name ?oName.
}
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P1811'), ('pName', 'list of episodes'), ('o', 'http://www.wikidata.org/entity/Q27665409'), ('oName', 'list of Cutthroat Kitchen episodes')]
# [('p', 'http://www.wikidata.org/prop/direct/P136'), ('pName', 'genre'), ('o', 'http://www.wikidata.org/entity/Q846662'), ('oName', 'game show')]
# [('p', 'http://www.wikidata.org/prop/direct/P407'), ('pName', 'language of work or name'), ('o', 'http://www.wikidata.org/entity/Q1860'), ('oName', 'English')]
# [('p', 'http://www.wikidata.org/prop/direct/P495'), ('pName', 'country of origin'), ('o', 'http://www.wikidata.org/entity/Q30'), ('oName', 'United States of America')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('o', 'http://www.wikidata.org/entity/Q5398426'), ('oName', 'television series')]
# [('p', 'http://www.wikidata.org/prop/direct/P437'), ('pName', 'distribution format'), ('o', 'http://www.wikidata.org/entity/Q723685'), ('oName', 'video on demand')]
# [('p', 'http://www.wikidata.org/prop/direct/P750'), ('pName', 'distributed by'), ('o', 'http://www.wikidata.org/entity/Q1630304'), ('oName', 'Hulu')]
# [('p', 'http://www.wikidata.org/prop/direct/P449'), ('pName', 'original broadcaster'), ('o', 'http://www.wikidata.org/entity/Q1435969'), ('oName', 'Food Network')]
# [('p', 'http://www.wikidata.org/prop/direct/P136'), ('pName', 'genre'), ('o', 'http://www.wikidata.org/entity/Q2111686'), ('oName', 'culinary art')]
# 9

# %%
# Q5398426 television series
queryString = """
SELECT DISTINCT ?televisionSeries ?televisionSeriesName
WHERE {
    wd:Q15594658 wdt:P31 ?televisionSeries .
   # ?televisionSeries sc:name ?televisionSeriesName.
}
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('televisionSeries', 'http://www.wikidata.org/entity/Q5398426'), ('televisionSeriesName', 'television series')]
# 1

# %% [markdown]
# Final query for this task

# %%
# write your final query
#Cutthroat Kitchen(wd:Q15594658) is an instance of (wdt:P31) of televisionSeries
queryString = """
SELECT DISTINCT ?televisionSeries ?televisionSeriesName
WHERE {
    wd:Q15594658 wdt:P31 ?televisionSeries .
   # ?televisionSeries sc:name ?televisionSeriesName.
}
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('televisionSeries', 'http://www.wikidata.org/entity/Q5398426'), ('televisionSeriesName', 'television series')]
# 1

# %% [markdown]
# ## Task 2
# Return the number of seasons and episodes per season of the tv series (the result set must be triples of season IRI, label and #episodes).

# %%
# write your queries
queryString = """
SELECT DISTINCT ?tvseries ?tvseriesName
WHERE {
    # ?tvseries wdt:P31 wd:Q5398426 .
   # ?tvseries sc:name ?tvseriesName.
}
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('tvseries', 'http://www.wikidata.org/entity/Q1154217'), ('tvseriesName', 'Ironfist Chinmi')]
# [('tvseries', 'http://www.wikidata.org/entity/Q691528'), ('tvseriesName', 'Wallace and Gromit')]
# [('tvseries', 'http://www.wikidata.org/entity/Q8193809'), ('tvseriesName', 'Shomuni')]
# [('tvseries', 'http://www.wikidata.org/entity/Q33323'), ('tvseriesName', 'Everybody Hates Chris')]
# [('tvseries', 'http://www.wikidata.org/entity/Q500769'), ('tvseriesName', 'Freaks and Geeks')]
# [('tvseries', 'http://www.wikidata.org/entity/Q8350955'), ('tvseriesName', 'Cordel Encantado')]
# [('tvseries', 'http://www.wikidata.org/entity/Q1145054'), ('tvseriesName', 'The NBC Mystery Movie')]
# [('tvseries', 'http://www.wikidata.org/entity/Q344081'), ('tvseriesName', 'Recess')]
# [('tvseries', 'http://www.wikidata.org/entity/Q13647845'), ('tvseriesName', 'Grijpstra & De Gier')]
# [('tvseries', 'http://www.wikidata.org/entity/Q708661'), ('tvseriesName', 'Lindenstraße')]
# [('tvseries', 'http://www.wikidata.org/entity/Q15099450'), ('tvseriesName', 'Prime Minister and I')]
# [('tvseries', 'http://www.wikidata.org/entity/Q15476155'), ('tvseriesName', 'The Full Sun')]
# [('tvseries', 'http://www.wikidata.org/entity/Q15933273'), ('tvseriesName', 'Big Man')]
# [('tvseries', 'http://www.wikidata.org/entity/Q548335'), ('tvseriesName', 'Angelina Ballerina')]
# [('tvseries', 'http://www.wikidata.org/entity/Q15581035'), ('tvseriesName', 'El cielo es para todos')]
# [('tvseries', 'http://www.wikidata.org/entity/Q15594658'), ('tvseriesName', 'Cutthroat Kitchen')]
# [('tvseries', 'http://www.wikidata.org/entity/Q15731300'), ('tvseriesName', 'Power Rangers Dino Charge')]
# [('tvseries', 'http://www.wikidata.org/entity/Q15737024'), ('tvseriesName', '37 Days')]
# [('tvseries', 'http://www.wikidata.org/entity/Q15933384'), ('tvseriesName', 'Special Affairs Team TEN')]
# [('tvseries', 'http://www.wikidata.org/entity/Q27889400'), ('tvseriesName', 'Power Rangers Ninja Steel')]
# 20

# %%
#Q27889400 Power Rangers Ninja Steel
queryString = """
SELECT DISTINCT ?pName ?oName
WHERE {
    wd:Q27889400 ?p ?o .
   # ?p sc:name ?pName.
   # ?o sc:name ?oName.
}
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('pName', 'follows'), ('oName', 'Power Rangers Dino Charge')]
# [('pName', 'original broadcaster'), ('oName', 'Nickelodeon')]
# [('pName', 'distributed by'), ('oName', 'Saban Entertainment')]
# [('pName', 'producer'), ('oName', 'Toei Company')]
# [('pName', 'creator'), ('oName', 'Toei Company')]
# [('pName', 'creator'), ('oName', 'Haim Saban')]
# [('pName', 'executive producer'), ('oName', 'Haim Saban')]
# [('pName', 'language of work or name'), ('oName', 'English')]
# [('pName', 'country of origin'), ('oName', 'United States of America')]
# [('pName', 'instance of'), ('oName', 'television series')]
# [('pName', 'distribution format'), ('oName', 'video on demand')]
# [('pName', 'distributed by'), ('oName', 'Netflix')]
# [('pName', 'distributed by'), ('oName', 'MarVista Entertainment')]
# [('pName', 'genre'), ('oName', 'tokusatsu')]
# [('pName', 'producer'), ('oName', 'Saban Capital Group')]
# [('pName', 'subclass of'), ('oName', 'Power Rangers')]
# [('pName', 'has part'), ('oName', 'Power Rangers Super Ninja Steel')]
# [('pName', 'based on'), ('oName', 'Shuriken Sentai Ninninger')]
# [('pName', 'executive producer'), ('oName', 'Judd Lynn')]
# [('pName', 'director'), ('oName', 'Judd Lynn')]
# 20

# %%
#Q15737024 Power Rangers Ninja Steel
queryString = """
SELECT DISTINCT ?sName ?p ?pName
WHERE {
     # ?s ?p wd:Q27889400 .
   # ?p sc:name ?pName.
   # ?s sc:name ?sName.

}
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('sName', 'Power Rangers Dino Charge'), ('p', 'http://www.wikidata.org/prop/direct/P156'), ('pName', 'followed by')]
# [('sName', 'Power Rangers Super Ninja Steel'), ('p', 'http://www.wikidata.org/prop/direct/P179'), ('pName', 'part of the series')]
# [('sName', 'Power Rangers Ninja Steel, season 1'), ('p', 'http://www.wikidata.org/prop/direct/P179'), ('pName', 'part of the series')]
# [('sName', 'Power Rangers Beast Morphers'), ('p', 'http://www.wikidata.org/prop/direct/P155'), ('pName', 'follows')]
# 4

# %%
#episodes per seasons 
# P179 part of the series
queryString = """
SELECT ?tvseriesName (COUNT(?seasonName) AS ?numseasons)
WHERE 
{
    # ?tvseries wdt:P31 wd:Q5398426 ;
            sc:name ?tvseriesName .
    # ?season wdt:P179 ?tvseries ;
       sc:name ?seasonName .

   FILTER REGEX(?seasonName, "season*")   
}
GROUP BY ?tvseriesName 
LIMIT 50
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('tvseriesName', 'Fantasy Island'), ('numseasons', '7')]
# [('tvseriesName', 'Mr. Novak'), ('numseasons', '2')]
# [('tvseriesName', 'American Chopper: Senior vs. Junior'), ('numseasons', '4')]
# [('tvseriesName', 'Family'), ('numseasons', '5')]
# [('tvseriesName', 'Jem'), ('numseasons', '3')]
# [('tvseriesName', 'Peter Punk'), ('numseasons', '2')]
# [('tvseriesName', 'Danmarks Næste Topmodel'), ('numseasons', '6')]
# [('tvseriesName', 'I liceali'), ('numseasons', '3')]
# [('tvseriesName', 'The Eleventh Hour'), ('numseasons', '3')]
# [('tvseriesName', 'Witchblade'), ('numseasons', '2')]
# [('tvseriesName', 'Armchair Thriller'), ('numseasons', '2')]
# [('tvseriesName', 'Survivor Philippines'), ('numseasons', '1')]
# [('tvseriesName', 'Bob Hope Presents the Chrysler Theatre'), ('numseasons', '4')]
# [('tvseriesName', 'The Colbys'), ('numseasons', '2')]
# [('tvseriesName', 'Star Trek: Strange New Worlds'), ('numseasons', '1')]
# [('tvseriesName', 'Class of the Titans'), ('numseasons', '1')]
# [('tvseriesName', "Bring 'Em Back Alive"), ('numseasons', '1')]
# [('tvseriesName', 'Homecoming'), ('numseasons', '2')]
# [('tvseriesName', 'World of Dance'), ('numseasons', '4')]
# [('tvseriesName', 'Tough as Nails'), ('numseasons', '2')]
# [('tvseriesName', 'Tracy e Polpetta'), ('numseasons', '6')]
# [('tvseriesName', 'Conan the Adventurer'), ('numseasons', '2')]
# [('tvseriesName', 'A Place to Call Home'), ('numseasons', '6')]
# [('tvseriesName', 'Bloodline'), ('numseasons', '3')]
# [('tvseriesName', 'The Mist'), ('numseasons', '1')]
# [('tvseriesName', 'Queer Eye'), ('numseasons', '5')]
# [('tvseriesName', 'Amazing Stories'), ('numseasons', '2')]
# [('tvseriesName', 'Alcoa Presents: One Step Beyond'), ('numseasons', '3')]
# [('tvseriesName', 'Sydney to the Max'), ('numseasons', '3')]
# [('tvseriesName', "Persia's Got Talent"), ('numseasons', '1')]
# [('tvseriesName', 'Golpe de Sorte'), ('numseasons', '4')]
# [('tvseriesName', 'Floor Is Lava'), ('numseasons', '1')]
# [('tvseriesName', 'Drag Race Holland'), ('numseasons', '1')]
# [('tvseriesName', 'Broken Arrow'), ('numseasons', '2')]
# [('tvseriesName', 'Graf Yoster'), ('numseasons', '5')]
# [('tvseriesName', "TV Reader's Digest"), ('numseasons', '2')]
# [('tvseriesName', 'Reign'), ('numseasons', '4')]
# [('tvseriesName', 'The Lawless Years'), ('numseasons', '3')]
# [('tvseriesName', 'The Path'), ('numseasons', '3')]
# [('tvseriesName', 'Nebbie e delitti'), ('numseasons', '3')]
# [('tvseriesName', 'Show Me Yours'), ('numseasons', '2')]
# [('tvseriesName', 'Drag Race Thailand'), ('numseasons', '2')]
# [('tvseriesName', 'Rawhide'), ('numseasons', '8')]
# [('tvseriesName', 'The Mod Squad'), ('numseasons', '5')]
# [('tvseriesName', 'The Restless Gun'), ('numseasons', '2')]
# [('tvseriesName', 'Deal or No Deal'), ('numseasons', '7')]
# [('tvseriesName', 'The Edison Twins'), ('numseasons', '6')]
# [('tvseriesName', 'Richard Diamond, Private Detective'), ('numseasons', '4')]
# [('tvseriesName', 'Bella and the Bulldogs'), ('numseasons', '2')]
# [('tvseriesName', "Asia's Got Talent"), ('numseasons', '3')]
# 50

# %%
#Q1615887 Everybody Hates Chris, season 3
queryString = """
SELECT DISTINCT ?pName ?oName
WHERE {
    wd:Q1615887 ?p ?o .
   # ?p sc:name ?pName.
   # ?o sc:name ?oName.
}
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('pName', 'part of the series'), ('oName', 'Everybody Hates Chris')]
# [('pName', 'original language of film or TV show'), ('oName', 'English')]
# [('pName', 'distribution format'), ('oName', 'video on demand')]
# [('pName', 'instance of'), ('oName', 'television series season')]
# [('pName', 'distribution format'), ('oName', 'digital download')]
# [('pName', 'distributed by'), ('oName', 'iTunes')]
# 6

# %% [markdown]
# Final query for this task

# %%
# write your final query
queryString = """
SELECT ?season ?seasonName (COUNT(?seasonName) AS ?numseasons)
WHERE 
{
    # ?tvseries wdt:P31 wd:Q5398426 ;
            sc:name ?tvseriesName .
    # ?season wdt:P179 ?tvseries ;
       sc:name ?seasonName .

   FILTER REGEX(?seasonName, "season*")   
}
GROUP BY ?season ?seasonName
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('season', 'http://www.wikidata.org/entity/Q64520767'), ('seasonName', 'Power Couple (Brazilian season 4)'), ('numseasons', '1')]
# [('season', 'http://www.wikidata.org/entity/Q18819122'), ('seasonName', 'Banshee, season 3'), ('numseasons', '1')]
# [('season', 'http://www.wikidata.org/entity/Q39072926'), ('seasonName', 'Instant Mom, season 2'), ('numseasons', '1')]
# [('season', 'http://www.wikidata.org/entity/Q56229087'), ('seasonName', 'Megasztár, season 3'), ('numseasons', '1')]
# [('season', 'http://www.wikidata.org/entity/Q66486674'), ('seasonName', 'Sacred Games, season 2'), ('numseasons', '1')]
# [('season', 'http://www.wikidata.org/entity/Q60521583'), ('seasonName', 'Food Paradise, season 8'), ('numseasons', '1')]
# [('season', 'http://www.wikidata.org/entity/Q60521582'), ('seasonName', 'Food Paradise, season 7'), ('numseasons', '1')]
# [('season', 'http://www.wikidata.org/entity/Q3730143'), ('seasonName', 'The Big C, season 3'), ('numseasons', '1')]
# [('season', 'http://www.wikidata.org/entity/Q60977808'), ('seasonName', 'The Ranch, season 3'), ('numseasons', '1')]
# [('season', 'http://www.wikidata.org/entity/Q50894634'), ('seasonName', 'Nix Festes, season 1'), ('numseasons', '1')]
# [('season', 'http://www.wikidata.org/entity/Q18351177'), ('seasonName', 'Alice, season 2'), ('numseasons', '1')]
# [('season', 'http://www.wikidata.org/entity/Q56489525'), ('seasonName', 'Blindspot, season 4'), ('numseasons', '1')]
# [('season', 'http://www.wikidata.org/entity/Q65078107'), ('seasonName', "America's Got Talent, season 14"), ('numseasons', '1')]
# [('season', 'http://www.wikidata.org/entity/Q30900599'), ('seasonName', 'You Me Her, season 1'), ('numseasons', '1')]
# [('season', 'http://www.wikidata.org/entity/Q21186109'), ('seasonName', 'Suits, season 5'), ('numseasons', '1')]
# [('season', 'http://www.wikidata.org/entity/Q16553844'), ('seasonName', 'The League, season 4'), ('numseasons', '1')]
# [('season', 'http://www.wikidata.org/entity/Q98801120'), ('seasonName', 'The Brady Bunch, season 5'), ('numseasons', '1')]
# [('season', 'http://www.wikidata.org/entity/Q56325028'), ('seasonName', 'Mindhunter, season 1'), ('numseasons', '1')]
# [('season', 'http://www.wikidata.org/entity/Q102350818'), ('seasonName', 'SOKO Donau, season 9'), ('numseasons', '1')]
# [('season', 'http://www.wikidata.org/entity/Q60765217'), ('seasonName', 'I Can See Your Voice Indonesia, season 2'), ('numseasons', '1')]
# [('season', 'http://www.wikidata.org/entity/Q60765211'), ('seasonName', 'I Can See Your Voice Indonesia, season 1'), ('numseasons', '1')]
# [('season', 'http://www.wikidata.org/entity/Q105038345'), ('seasonName', 'The Voice (U.S. season 19)'), ('numseasons', '1')]
# [('season', 'http://www.wikidata.org/entity/Q63524413'), ('seasonName', "Schitt's Creek, season 3"), ('numseasons', '1')]
# [('season', 'http://www.wikidata.org/entity/Q99745924'), ('seasonName', 'Dance Smash, season 1'), ('numseasons', '1')]
# [('season', 'http://www.wikidata.org/entity/Q65057978'), ('seasonName', "Ellen's Game of Games, season 2"), ('numseasons', '1')]
# [('season', 'http://www.wikidata.org/entity/Q25217857'), ('seasonName', 'The Bachelor, season 2'), ('numseasons', '1')]
# [('season', 'http://www.wikidata.org/entity/Q101229740'), ('seasonName', 'Alfons Åberg, season 3'), ('numseasons', '1')]
# [('season', 'http://www.wikidata.org/entity/Q3729398'), ('seasonName', 'Cagney & Lacey, season 7'), ('numseasons', '1')]
# [('season', 'http://www.wikidata.org/entity/Q16553988'), ('seasonName', 'V.I.P., season 3'), ('numseasons', '1')]
# [('season', 'http://www.wikidata.org/entity/Q25218140'), ('seasonName', 'Shark Tank, Australia season 2'), ('numseasons', '1')]
# [('season', 'http://www.wikidata.org/entity/Q28453361'), ('seasonName', 'Doble Kara, season 3'), ('numseasons', '1')]
# [('season', 'http://www.wikidata.org/entity/Q28451291'), ('seasonName', 'The Real Housewives of Orange County, season 7'), ('numseasons', '1')]
# [('season', 'http://www.wikidata.org/entity/Q98355691'), ('seasonName', 'The Adventures of Ozzie and Harriet, season 11'), ('numseasons', '1')]
# [('season', 'http://www.wikidata.org/entity/Q99743321'), ('seasonName', 'Pawn Stars, season 4'), ('numseasons', '1')]
# [('season', 'http://www.wikidata.org/entity/Q69355558'), ('seasonName', 'Shameless, season 10'), ('numseasons', '1')]
# [('season', 'http://www.wikidata.org/entity/Q30901596'), ('seasonName', 'El Ministerio del Tiempo, season 3'), ('numseasons', '1')]
# [('season', 'http://www.wikidata.org/entity/Q3726997'), ('seasonName', 'The Jeffersons, season 5'), ('numseasons', '1')]
# [('season', 'http://www.wikidata.org/entity/Q30900792'), ('seasonName', 'One Day at a Time, season 2'), ('numseasons', '1')]
# [('season', 'http://www.wikidata.org/entity/Q94096400'), ('seasonName', 'Doogie Howser, M.D., season 1'), ('numseasons', '1')]
# [('season', 'http://www.wikidata.org/entity/Q97370183'), ('seasonName', 'Perfect Strangers, season 8'), ('numseasons', '1')]
# [('season', 'http://www.wikidata.org/entity/Q97370069'), ('seasonName', 'The Onedin Line, season 4'), ('numseasons', '1')]
# [('season', 'http://www.wikidata.org/entity/Q97370040'), ('seasonName', 'Crazy like a Fox, season 1'), ('numseasons', '1')]
# [('season', 'http://www.wikidata.org/entity/Q59386626'), ('seasonName', 'Scènes de ménage, season 9'), ('numseasons', '1')]
# [('season', 'http://www.wikidata.org/entity/Q3729041'), ('seasonName', 'Law & Order: Special Victims Unit, season 12'), ('numseasons', '1')]
# [('season', 'http://www.wikidata.org/entity/Q12096640'), ('seasonName', '2nd season of The Voice Ukraine'), ('numseasons', '1')]
# [('season', 'http://www.wikidata.org/entity/Q17329040'), ('seasonName', 'The Voice of China, season 3'), ('numseasons', '1')]
# [('season', 'http://www.wikidata.org/entity/Q17153875'), ('seasonName', 'The Bob Newhart Show, season 1'), ('numseasons', '1')]
# [('season', 'http://www.wikidata.org/entity/Q17152873'), ('seasonName', 'The Bob Newhart Show, season 6'), ('numseasons', '1')]
# [('season', 'http://www.wikidata.org/entity/Q18636778'), ('seasonName', 'Storage Wars, season 6'), ('numseasons', '1')]
# [('season', 'http://www.wikidata.org/entity/Q104913539'), ('seasonName', 'Kath & Kim season 1'), ('numseasons', '1')]
# [('season', 'http://www.wikidata.org/entity/Q15194029'), ('seasonName', 'Vain elämää, season 2'), ('numseasons', '1')]
# [('season', 'http://www.wikidata.org/entity/Q70142759'), ('seasonName', 'Vain elämää, season 10'), ('numseasons', '1')]
# [('season', 'http://www.wikidata.org/entity/Q61356268'), ('seasonName', 'Vild med dans, season 16'), ('numseasons', '1')]
# [('season', 'http://www.wikidata.org/entity/Q11889190'), ('seasonName', 'Putous, season 4'), ('numseasons', '1')]
# [('season', 'http://www.wikidata.org/entity/Q7715216'), ('seasonName', 'The Bachelor, season 15'), ('numseasons', '1')]
# [('season', 'http://www.wikidata.org/entity/Q7715212'), ('seasonName', 'The Bachelor, season 11'), ('numseasons', '1')]
# [('season', 'http://www.wikidata.org/entity/Q41535948'), ('seasonName', 'Soy Luna, season 2'), ('numseasons', '1')]
# [('season', 'http://www.wikidata.org/entity/Q24042652'), ('seasonName', 'La familia P. Luche, season 3'), ('numseasons', '1')]
# [('season', 'http://www.wikidata.org/entity/Q66619395'), ('seasonName', 'Rosario Tijeras, season 3'), ('numseasons', '1')]
# [('season', 'http://www.wikidata.org/entity/Q3468983'), ('seasonName', 'Star Trek: The Next Generation, season 5'), ('numseasons', '1')]
# [('season', 'http://www.wikidata.org/entity/Q7579107'), ('seasonName', 'Spooks, season 3'), ('numseasons', '1')]
# [('season', 'http://www.wikidata.org/entity/Q16552699'), ('seasonName', 'Wagon Train, season 1'), ('numseasons', '1')]
# [('season', 'http://www.wikidata.org/entity/Q106696020'), ('seasonName', 'Hey Arnold!, season 3'), ('numseasons', '1')]
# [('season', 'http://www.wikidata.org/entity/Q100990501'), ('seasonName', 'Hallo, Onkel Doc!, season 5'), ('numseasons', '1')]
# [('season', 'http://www.wikidata.org/entity/Q16850678'), ('seasonName', 'Johnny Test, season 2'), ('numseasons', '1')]
# [('season', 'http://www.wikidata.org/entity/Q3727539'), ('seasonName', 'Alfred Hitchcock Presents, season 7'), ('numseasons', '1')]
# [('season', 'http://www.wikidata.org/entity/Q105491052'), ('seasonName', 'In the Heat of the Night, season 6'), ('numseasons', '1')]
# [('season', 'http://www.wikidata.org/entity/Q2127141'), ('seasonName', 'Spoed, season 1'), ('numseasons', '1')]
# [('season', 'http://www.wikidata.org/entity/Q39072235'), ('seasonName', 'Gotham, season 4'), ('numseasons', '1')]
# [('season', 'http://www.wikidata.org/entity/Q2083225'), ('seasonName', '90210, season 5'), ('numseasons', '1')]
# [('season', 'http://www.wikidata.org/entity/Q29000871'), ('seasonName', 'Arrow, season 5'), ('numseasons', '1')]
# [('season', 'http://www.wikidata.org/entity/Q17079382'), ('seasonName', 'Saturday Night Live, season 40'), ('numseasons', '1')]
# [('season', 'http://www.wikidata.org/entity/Q7426684'), ('seasonName', 'Saturday Night Live, season 21'), ('numseasons', '1')]
# [('season', 'http://www.wikidata.org/entity/Q5334460'), ('seasonName', 'Ed, Edd n Eddy, season 3'), ('numseasons', '1')]
# [('season', 'http://www.wikidata.org/entity/Q12981844'), ('seasonName', 'The DuPont Show with June Allyson, season 1'), ('numseasons', '1')]
# [('season', 'http://www.wikidata.org/entity/Q12912808'), ('seasonName', 'Schlitz Playhouse of Stars, season 6'), ('numseasons', '1')]
# [('season', 'http://www.wikidata.org/entity/Q51800792'), ('seasonName', 'Airwolf, season 4'), ('numseasons', '1')]
# [('season', 'http://www.wikidata.org/entity/Q98107757'), ('seasonName', 'Big Town, season 5'), ('numseasons', '1')]
# [('season', 'http://www.wikidata.org/entity/Q98107759'), ('seasonName', 'Big Town, season 6'), ('numseasons', '1')]
# [('season', 'http://www.wikidata.org/entity/Q16552853'), ('seasonName', 'Dog with a Blog, season 2'), ('numseasons', '1')]
# [('season', 'http://www.wikidata.org/entity/Q15102594'), ('seasonName', 'The Voice of Germany, season 3'), ('numseasons', '1')]
# [('season', 'http://www.wikidata.org/entity/Q51643311'), ('seasonName', 'New Girl, season 7'), ('numseasons', '1')]
# [('season', 'http://www.wikidata.org/entity/Q28657742'), ('seasonName', 'Santa Clarita Diet, season 1'), ('numseasons', '1')]
# [('season', 'http://www.wikidata.org/entity/Q9670762'), ('seasonName', 'CSI: Crime Scene Investigation, season 14'), ('numseasons', '1')]
# [('season', 'http://www.wikidata.org/entity/Q65084975'), ('seasonName', 'Supergirl, season 5'), ('numseasons', '1')]
# [('season', 'http://www.wikidata.org/entity/Q3469079'), ('seasonName', "That '70s Show, season 7"), ('numseasons', '1')]
# [('season', 'http://www.wikidata.org/entity/Q1611030'), ('seasonName', 'Doctor Who, season 13'), ('numseasons', '1')]
# [('season', 'http://www.wikidata.org/entity/Q1610863'), ('seasonName', 'Doctor Who, season 10'), ('numseasons', '1')]
# [('season', 'http://www.wikidata.org/entity/Q20987112'), ('seasonName', 'NCIS: Los Angeles, season 7'), ('numseasons', '1')]
# [('season', 'http://www.wikidata.org/entity/Q17629959'), ('seasonName', 'Superman: The Animated Series, season 2'), ('numseasons', '1')]
# [('season', 'http://www.wikidata.org/entity/Q3727165'), ('seasonName', 'Il maresciallo Rocca, season 1'), ('numseasons', '1')]
# [('season', 'http://www.wikidata.org/entity/Q2661631'), ('seasonName', 'Buffy the Vampire Slayer, season 4'), ('numseasons', '1')]
# [('season', 'http://www.wikidata.org/entity/Q3465736'), ('seasonName', 'Mad Men, season 1'), ('numseasons', '1')]
# [('season', 'http://www.wikidata.org/entity/Q16206901'), ('seasonName', 'Casualty, season 28'), ('numseasons', '1')]
# [('season', 'http://www.wikidata.org/entity/Q65158256'), ('seasonName', 'The Walking Dead, season 10'), ('numseasons', '1')]
# [('season', 'http://www.wikidata.org/entity/Q3727918'), ('seasonName', 'Californication, season 6'), ('numseasons', '1')]
# [('season', 'http://www.wikidata.org/entity/Q3730563'), ('seasonName', "Wingin' It, season 1"), ('numseasons', '1')]
# [('season', 'http://www.wikidata.org/entity/Q3468898'), ('seasonName', 'Star Trek: Enterprise, season 4'), ('numseasons', '1')]
# [('season', 'http://www.wikidata.org/entity/Q3468607'), ('seasonName', 'Touch, season 2'), ('numseasons', '1')]
# [('season', 'http://www.wikidata.org/entity/Q105103817'), ('seasonName', 'The Life and Times of Grizzly Adams, season 1'), ('numseasons', '1')]
# 100

# %% [markdown]
# ## Task 3
# Get the number of episodes in which the cast members played a role. Who are the most present actors? (the result set must be a list of triples actor/actress IRI, label and #episodes)

# %%
# write your queries
#Q27889400 Power Rangers Ninja Steel
queryString = """
SELECT DISTINCT ?p ?pName ?oName
WHERE {
    wd:Q27889400 ?p ?o .
   # ?p sc:name ?pName.
   # ?o sc:name ?oName.
}
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P155'), ('pName', 'follows'), ('oName', 'Power Rangers Dino Charge')]
# [('p', 'http://www.wikidata.org/prop/direct/P449'), ('pName', 'original broadcaster'), ('oName', 'Nickelodeon')]
# [('p', 'http://www.wikidata.org/prop/direct/P750'), ('pName', 'distributed by'), ('oName', 'Saban Entertainment')]
# [('p', 'http://www.wikidata.org/prop/direct/P162'), ('pName', 'producer'), ('oName', 'Toei Company')]
# [('p', 'http://www.wikidata.org/prop/direct/P170'), ('pName', 'creator'), ('oName', 'Toei Company')]
# [('p', 'http://www.wikidata.org/prop/direct/P170'), ('pName', 'creator'), ('oName', 'Haim Saban')]
# [('p', 'http://www.wikidata.org/prop/direct/P1431'), ('pName', 'executive producer'), ('oName', 'Haim Saban')]
# [('p', 'http://www.wikidata.org/prop/direct/P407'), ('pName', 'language of work or name'), ('oName', 'English')]
# [('p', 'http://www.wikidata.org/prop/direct/P495'), ('pName', 'country of origin'), ('oName', 'United States of America')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('oName', 'television series')]
# [('p', 'http://www.wikidata.org/prop/direct/P437'), ('pName', 'distribution format'), ('oName', 'video on demand')]
# [('p', 'http://www.wikidata.org/prop/direct/P750'), ('pName', 'distributed by'), ('oName', 'Netflix')]
# [('p', 'http://www.wikidata.org/prop/direct/P750'), ('pName', 'distributed by'), ('oName', 'MarVista Entertainment')]
# [('p', 'http://www.wikidata.org/prop/direct/P136'), ('pName', 'genre'), ('oName', 'tokusatsu')]
# [('p', 'http://www.wikidata.org/prop/direct/P162'), ('pName', 'producer'), ('oName', 'Saban Capital Group')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('oName', 'Power Rangers')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('oName', 'Power Rangers Super Ninja Steel')]
# [('p', 'http://www.wikidata.org/prop/direct/P144'), ('pName', 'based on'), ('oName', 'Shuriken Sentai Ninninger')]
# [('p', 'http://www.wikidata.org/prop/direct/P1431'), ('pName', 'executive producer'), ('oName', 'Judd Lynn')]
# [('p', 'http://www.wikidata.org/prop/direct/P57'), ('pName', 'director'), ('oName', 'Judd Lynn')]
# 20

# %%
#P57 director
queryString = """
SELECT DISTINCT ?s ?sName ?oName
WHERE {
   # ?s wdt:P57 ?o .
   # ?s sc:name ?sName.
   # ?o sc:name ?oName.
}
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('s', 'http://www.wikidata.org/entity/Q8193809'), ('sName', 'Shomuni'), ('oName', 'Takayoshi Watanabe')]
# [('s', 'http://www.wikidata.org/entity/Q21008514'), ('sName', 'Murder in Pacot'), ('oName', 'Raoul Peck')]
# [('s', 'http://www.wikidata.org/entity/Q8452990'), ('sName', "Sunday League - Pepik Hnatek's Final Match"), ('oName', 'Jan Prušinovský')]
# [('s', 'http://www.wikidata.org/entity/Q3611806'), ('sName', 'Alimony'), ('oName', 'Emmett J. Flynn')]
# [('s', 'http://www.wikidata.org/entity/Q8350955'), ('sName', 'Cordel Encantado'), ('oName', 'Amora Mautner')]
# [('s', 'http://www.wikidata.org/entity/Q20949971'), ('sName', 'Stolen Heaven'), ('oName', 'Andrew L. Stone')]
# [('s', 'http://www.wikidata.org/entity/Q21646939'), ('sName', 'Roommate'), ('oName', 'Takeshi Furusawa')]
# [('s', 'http://www.wikidata.org/entity/Q18040186'), ('sName', "Charlie Don't Surf"), ('oName', 'Jason Bloom')]
# [('s', 'http://www.wikidata.org/entity/Q23419147'), ('sName', 'Anna Regina'), ('oName', 'Peter Kosminsky')]
# [('s', 'http://www.wikidata.org/entity/Q23419171'), ('sName', 'Entirely Beloved'), ('oName', 'Peter Kosminsky')]
# [('s', 'http://www.wikidata.org/entity/Q16943346'), ('sName', 'Mabudachi'), ('oName', 'Tomoyuki Furumaya')]
# [('s', 'http://www.wikidata.org/entity/Q13643224'), ('sName', 'Carl & Bertha'), ('oName', 'Till Endemann')]
# [('s', 'http://www.wikidata.org/entity/Q15475237'), ('sName', 'Mediastan'), ('oName', 'Johannes Wahlström')]
# [('s', 'http://www.wikidata.org/entity/Q15464247'), ('sName', 'What the Fish'), ('oName', 'Gurmeet Singh')]
# [('s', 'http://www.wikidata.org/entity/Q15584559'), ('sName', 'Salvation Nell'), ('oName', 'George E. Middleton')]
# [('s', 'http://www.wikidata.org/entity/Q15724887'), ('sName', 'Bahu Heba Emiti'), ('oName', 'Vijay Bhaskar')]
# [('s', 'http://www.wikidata.org/entity/Q15725414'), ('sName', 'Haata Dhari Chaaluthaa'), ('oName', 'Himanshu Parija')]
# [('s', 'http://www.wikidata.org/entity/Q15725300'), ('sName', 'Sakhi Rahila Ae Singha Duara'), ('oName', 'Sanjay Nayak')]
# [('s', 'http://www.wikidata.org/entity/Q15724803'), ('sName', 'Basanti Apa'), ('oName', 'Jalal Adeni')]
# [('s', 'http://www.wikidata.org/entity/Q15724695'), ('sName', 'Priyatama'), ('oName', 'Biswajit Das')]
# 20

# %%
#Q21008514 Murder in Pacot
queryString = """
SELECT DISTINCT ?p ?pName ?oName
WHERE {
   wd:Q21008514 ?p ?o .
   # ?p sc:name ?pName.
   # ?o sc:name ?oName.
}
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P57'), ('pName', 'director'), ('oName', 'Raoul Peck')]
# [('p', 'http://www.wikidata.org/prop/direct/P162'), ('pName', 'producer'), ('oName', 'Rémi Grellety')]
# [('p', 'http://www.wikidata.org/prop/direct/P344'), ('pName', 'director of photography'), ('oName', 'Éric Guichard')]
# [('p', 'http://www.wikidata.org/prop/direct/P58'), ('pName', 'screenwriter'), ('oName', 'Lyonel Trouillot')]
# [('p', 'http://www.wikidata.org/prop/direct/P161'), ('pName', 'cast member'), ('oName', 'Thibault Vinçon')]
# [('p', 'http://www.wikidata.org/prop/direct/P86'), ('pName', 'composer'), ('oName', 'Alexei Gennadjewitsch Aigi')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('oName', 'film')]
# [('p', 'http://www.wikidata.org/prop/direct/P495'), ('pName', 'country of origin'), ('oName', 'France')]
# [('p', 'http://www.wikidata.org/prop/direct/P364'), ('pName', 'original language of film or TV show'), ('oName', 'French')]
# [('p', 'http://www.wikidata.org/prop/direct/P495'), ('pName', 'country of origin'), ('oName', 'Norway')]
# [('p', 'http://www.wikidata.org/prop/direct/P1981'), ('pName', 'FSK film rating'), ('oName', 'FSK 12')]
# [('p', 'http://www.wikidata.org/prop/direct/P462'), ('pName', 'color'), ('oName', 'color')]
# [('p', 'http://www.wikidata.org/prop/direct/P495'), ('pName', 'country of origin'), ('oName', 'Haiti')]
# [('p', 'http://www.wikidata.org/prop/direct/P915'), ('pName', 'filming location'), ('oName', 'Port-au-Prince')]
# [('p', 'http://www.wikidata.org/prop/direct/P161'), ('pName', 'cast member'), ('oName', 'Alex Descas')]
# [('p', 'http://www.wikidata.org/prop/direct/P161'), ('pName', 'cast member'), ('oName', 'Zinedine Soualem')]
# [('p', 'http://www.wikidata.org/prop/direct/P161'), ('pName', 'cast member'), ('oName', 'Ayọ')]
# 17

# %%
#number of films actor/actress act
#P161 cast member
queryString = """
SELECT DISTINCT ?actor ?actorName (COUNT(?filmName) AS ?numfilm)
WHERE {
   # ?film wdt:P161 ?actor .
   # ?film sc:name ?filmName .
   # ?actor sc:name ?actorName .
}
GROUP BY ?actor ?actorName
ORDER BY DESC (?numfilm)
LIMIT 50
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('actor', 'http://www.wikidata.org/entity/Q2735277'), ('actorName', 'Prem Nazir'), ('numfilm', '525')]
# [('actor', 'http://www.wikidata.org/entity/Q946745'), ('actorName', 'Broncho Billy Anderson'), ('numfilm', '351')]
# [('actor', 'http://www.wikidata.org/entity/Q379604'), ('actorName', 'Mithun Chakraborty'), ('numfilm', '346')]
# [('actor', 'http://www.wikidata.org/entity/Q2721855'), ('actorName', 'Mammootty'), ('numfilm', '340')]
# [('actor', 'http://www.wikidata.org/entity/Q72911'), ('actorName', 'Oliver Hardy'), ('numfilm', '335')]
# [('actor', 'http://www.wikidata.org/entity/Q317574'), ('actorName', 'Mack Sennett'), ('numfilm', '297')]
# [('actor', 'http://www.wikidata.org/entity/Q316955'), ('actorName', 'Michael Dorn'), ('numfilm', '294')]
# [('actor', 'http://www.wikidata.org/entity/Q2050534'), ('actorName', 'Mohanlal'), ('numfilm', '291')]
# [('actor', 'http://www.wikidata.org/entity/Q184572'), ('actorName', 'Martin Sheen'), ('numfilm', '286')]
# [('actor', 'http://www.wikidata.org/entity/Q32522'), ('actorName', 'Jennifer Aniston'), ('numfilm', '285')]
# [('actor', 'http://www.wikidata.org/entity/Q179041'), ('actorName', 'Lisa Kudrow'), ('numfilm', '279')]
# [('actor', 'http://www.wikidata.org/entity/Q1395425'), ('actorName', 'Sivaji Ganesan'), ('numfilm', '279')]
# [('actor', 'http://www.wikidata.org/entity/Q58912'), ('actorName', 'Courteney Cox'), ('numfilm', '278')]
# [('actor', 'http://www.wikidata.org/entity/Q16296'), ('actorName', 'Patrick Stewart'), ('numfilm', '274')]
# [('actor', 'http://www.wikidata.org/entity/Q171758'), ('actorName', 'Matthew Perry'), ('numfilm', '270')]
# [('actor', 'http://www.wikidata.org/entity/Q188792'), ('actorName', 'David Schwimmer'), ('numfilm', '268')]
# [('actor', 'http://www.wikidata.org/entity/Q103946'), ('actorName', 'Kiefer Sutherland'), ('numfilm', '262')]
# [('actor', 'http://www.wikidata.org/entity/Q277417'), ('actorName', 'Madhu'), ('numfilm', '261')]
# [('actor', 'http://www.wikidata.org/entity/Q186896'), ('actorName', 'Matt LeBlanc'), ('numfilm', '255')]
# [('actor', 'http://www.wikidata.org/entity/Q3595596'), ('actorName', 'Adoor Bhasi'), ('numfilm', '252')]
# [('actor', 'http://www.wikidata.org/entity/Q6122250'), ('actorName', 'Jagathy Sreekumar'), ('numfilm', '251')]
# [('actor', 'http://www.wikidata.org/entity/Q1344801'), ('actorName', 'Harry Carey'), ('numfilm', '251')]
# [('actor', 'http://www.wikidata.org/entity/Q1361838'), ('actorName', 'Francis Ford'), ('numfilm', '249')]
# [('actor', 'http://www.wikidata.org/entity/Q3126801'), ('actorName', 'Hank Mann'), ('numfilm', '247')]
# [('actor', 'http://www.wikidata.org/entity/Q918741'), ('actorName', 'Harry Todd'), ('numfilm', '241')]
# [('actor', 'http://www.wikidata.org/entity/Q513849'), ('actorName', 'Bess Flowers'), ('numfilm', '240')]
# [('actor', 'http://www.wikidata.org/entity/Q104109'), ('actorName', 'Mary Pickford'), ('numfilm', '236')]
# [('actor', 'http://www.wikidata.org/entity/Q379157'), ('actorName', 'Dharmendra'), ('numfilm', '236')]
# [('actor', 'http://www.wikidata.org/entity/Q355209'), ('actorName', 'Richard Schiff'), ('numfilm', '232')]
# [('actor', 'http://www.wikidata.org/entity/Q229487'), ('actorName', 'Allison Janney'), ('numfilm', '231')]
# [('actor', 'http://www.wikidata.org/entity/Q2522555'), ('actorName', 'Victor Potel'), ('numfilm', '231')]
# [('actor', 'http://www.wikidata.org/entity/Q311453'), ('actorName', 'Brent Spiner'), ('numfilm', '229')]
# [('actor', 'http://www.wikidata.org/entity/Q232945'), ('actorName', 'Marina Sirtis'), ('numfilm', '226')]
# [('actor', 'http://www.wikidata.org/entity/Q278980'), ('actorName', 'Akkineni Nageswara Rao'), ('numfilm', '222')]
# [('actor', 'http://www.wikidata.org/entity/Q995160'), ('actorName', 'Bryant Washburn'), ('numfilm', '220')]
# [('actor', 'http://www.wikidata.org/entity/Q346595'), ('actorName', 'Jonathan Frakes'), ('numfilm', '220')]
# [('actor', 'http://www.wikidata.org/entity/Q313789'), ('actorName', 'Robert Picardo'), ('numfilm', '220')]
# [('actor', 'http://www.wikidata.org/entity/Q308124'), ('actorName', 'Anthony LaPaglia'), ('numfilm', '216')]
# [('actor', 'http://www.wikidata.org/entity/Q966972'), ('actorName', 'Owen Moore'), ('numfilm', '216')]
# [('actor', 'http://www.wikidata.org/entity/Q1281212'), ('actorName', 'Moe Howard'), ('numfilm', '214')]
# [('actor', 'http://www.wikidata.org/entity/Q255577'), ('actorName', 'Bebe Daniels'), ('numfilm', '214')]
# [('actor', 'http://www.wikidata.org/entity/Q352180'), ('actorName', 'Bradley Whitford'), ('numfilm', '210')]
# [('actor', 'http://www.wikidata.org/entity/Q1383202'), ('actorName', 'Leo White'), ('numfilm', '206')]
# [('actor', 'http://www.wikidata.org/entity/Q661079'), ('actorName', 'Arthur V. Johnson'), ('numfilm', '206')]
# [('actor', 'http://www.wikidata.org/entity/Q508858'), ('actorName', 'Alice Joyce'), ('numfilm', '205')]
# [('actor', 'http://www.wikidata.org/entity/Q5225034'), ('actorName', 'Mihir Das'), ('numfilm', '204')]
# [('actor', 'http://www.wikidata.org/entity/Q1621558'), ('actorName', 'Hobart Bosworth'), ('numfilm', '203')]
# [('actor', 'http://www.wikidata.org/entity/Q256968'), ('actorName', 'Florence Lawrence'), ('numfilm', '203')]
# [('actor', 'http://www.wikidata.org/entity/Q104340'), ('actorName', 'Harold Lloyd'), ('numfilm', '200')]
# [('actor', 'http://www.wikidata.org/entity/Q6167450'), ('actorName', 'Jayabharathi'), ('numfilm', '197')]
# 50

# %%
#
queryString = """
SELECT DISTINCT ?tvseriesName ?actorName
WHERE {
    # ?tvseries wdt:P31 wd:Q5398426 ;
            sc:name ?tvseriesName .
   # ?tvseries wdt:P161 ?actor .
   # ?actor sc:name ?actorName .
}
LIMIT 50
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('tvseriesName', 'Everybody Hates Chris'), ('actorName', 'Terry Crews')]
# [('tvseriesName', 'Everybody Hates Chris'), ('actorName', 'Imani Hakim')]
# [('tvseriesName', 'Everybody Hates Chris'), ('actorName', 'Tichina Arnold')]
# [('tvseriesName', 'Everybody Hates Chris'), ('actorName', 'Tyler James Williams')]
# [('tvseriesName', 'Everybody Hates Chris'), ('actorName', 'Vincent Martella')]
# [('tvseriesName', 'Everybody Hates Chris'), ('actorName', 'Tequan Richmond')]
# [('tvseriesName', 'Freaks and Geeks'), ('actorName', 'Linda Cardellini')]
# [('tvseriesName', 'Freaks and Geeks'), ('actorName', 'Samm Levine')]
# [('tvseriesName', 'Freaks and Geeks'), ('actorName', 'Jerry Messing')]
# [('tvseriesName', 'Freaks and Geeks'), ('actorName', 'Busy Philipps')]
# [('tvseriesName', 'Freaks and Geeks'), ('actorName', 'Becky Ann Baker')]
# [('tvseriesName', 'Freaks and Geeks'), ('actorName', 'Thomas F. Wilson')]
# [('tvseriesName', 'Freaks and Geeks'), ('actorName', 'Joe Flaherty')]
# [('tvseriesName', 'Freaks and Geeks'), ('actorName', 'Natasha Melnick')]
# [('tvseriesName', 'Freaks and Geeks'), ('actorName', 'John Francis Daley')]
# [('tvseriesName', 'Freaks and Geeks'), ('actorName', 'Seth Rogen')]
# [('tvseriesName', 'Freaks and Geeks'), ('actorName', 'Dave Allen')]
# [('tvseriesName', 'Freaks and Geeks'), ('actorName', 'James Franco')]
# [('tvseriesName', 'Freaks and Geeks'), ('actorName', 'Chauncey Leopardi')]
# [('tvseriesName', 'Freaks and Geeks'), ('actorName', 'Jason Segel')]
# [('tvseriesName', 'Freaks and Geeks'), ('actorName', 'Ben Foster')]
# [('tvseriesName', 'Freaks and Geeks'), ('actorName', 'Martin Starr')]
# [('tvseriesName', 'Freaks and Geeks'), ('actorName', 'Kayla Ewell')]
# [('tvseriesName', 'Freaks and Geeks'), ('actorName', 'Shaun Weiss')]
# [('tvseriesName', 'Freaks and Geeks'), ('actorName', 'Steve Bannos')]
# [('tvseriesName', 'Freaks and Geeks'), ('actorName', 'Sarah Hagan')]
# [('tvseriesName', 'Cordel Encantado'), ('actorName', 'Cauã Reymond')]
# [('tvseriesName', 'The NBC Mystery Movie'), ('actorName', 'Patrick McGoohan')]
# [('tvseriesName', 'The NBC Mystery Movie'), ('actorName', 'Peter Falk')]
# [('tvseriesName', 'The NBC Mystery Movie'), ('actorName', 'Susan Saint James')]
# [('tvseriesName', 'The NBC Mystery Movie'), ('actorName', 'Jessica Walter')]
# [('tvseriesName', 'The NBC Mystery Movie'), ('actorName', 'Dennis Weaver')]
# [('tvseriesName', 'Grijpstra & De Gier'), ('actorName', 'Jack Wouterse')]
# [('tvseriesName', 'Lindenstraße'), ('actorName', 'Sontje Peplow')]
# [('tvseriesName', 'Lindenstraße'), ('actorName', 'Liz Baffoe')]
# [('tvseriesName', 'Lindenstraße'), ('actorName', 'Reinhold Lampe')]
# [('tvseriesName', 'Lindenstraße'), ('actorName', 'Christoph Wortberg')]
# [('tvseriesName', 'Lindenstraße'), ('actorName', 'Gérard Hérold')]
# [('tvseriesName', 'Lindenstraße'), ('actorName', 'Herbert Steinmetz')]
# [('tvseriesName', 'Lindenstraße'), ('actorName', 'Annette Kreft')]
# [('tvseriesName', 'Lindenstraße'), ('actorName', 'Tatjana Blacher')]
# [('tvseriesName', 'Lindenstraße'), ('actorName', 'Dietrich Siegl')]
# [('tvseriesName', 'Lindenstraße'), ('actorName', 'Moritz Hein')]
# [('tvseriesName', 'Lindenstraße'), ('actorName', 'Martin Walde')]
# [('tvseriesName', 'Lindenstraße'), ('actorName', 'Anja Antonowicz')]
# [('tvseriesName', 'Lindenstraße'), ('actorName', 'Annemarie Wendl')]
# [('tvseriesName', 'Lindenstraße'), ('actorName', 'Philipp Sonntag')]
# [('tvseriesName', 'Lindenstraße'), ('actorName', 'Ulrike C. Tscharre')]
# [('tvseriesName', 'Lindenstraße'), ('actorName', 'Thorsten Nindel')]
# [('tvseriesName', 'Lindenstraße'), ('actorName', 'Til Schweiger')]
# 50

# %%
#Q8197668 FILM Idiot Love
queryString = """
SELECT DISTINCT ?pName ?oName
WHERE {
   wd:Q8197668 ?p ?o.
   # ?o sc:name ?oName .
   # ?p sc:name ?pName .
}
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('pName', 'genre'), ('oName', 'drama')]
# [('pName', 'cast member'), ('oName', 'Marc Cartes i Ivern')]
# [('pName', 'cast member'), ('oName', 'Roger Casamajor')]
# [('pName', 'cast member'), ('oName', 'Jordi Dauder')]
# [('pName', 'cast member'), ('oName', 'Sophie Evans')]
# [('pName', 'cast member'), ('oName', 'Santi Millán')]
# [('pName', 'cast member'), ('oName', 'Mercè Pons')]
# [('pName', 'cast member'), ('oName', 'Cayetana Guillén Cuervo')]
# [('pName', 'instance of'), ('oName', 'film')]
# [('pName', 'original language of film or TV show'), ('oName', 'Spanish')]
# [('pName', 'country of origin'), ('oName', 'Spain')]
# [('pName', 'director'), ('oName', 'Ventura Pons')]
# [('pName', 'composer'), ('oName', 'Carles Cases')]
# 13

# %%
# Q2735277 actor Prem Nazir
queryString = """
SELECT DISTINCT ?pName ?oName
WHERE {
   wd:Q2735277 ?p ?o.
   # ?o sc:name ?oName .
   # ?p sc:name ?pName .
}
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('pName', 'native language'), ('oName', 'Malayalam')]
# [('pName', 'occupation'), ('oName', 'actor')]
# [('pName', 'filmography'), ('oName', 'Prem Nazir filmography')]
# [('pName', 'religion'), ('oName', 'Islam')]
# [('pName', 'languages spoken, written or signed'), ('oName', 'Malayalam')]
# [('pName', 'award received'), ('oName', 'Padma Shri in arts')]
# [('pName', 'award received'), ('oName', 'Padma Bhushan')]
# [('pName', 'place of birth'), ('oName', 'Chirayinkizhu Block Panchayat')]
# [('pName', 'place of death'), ('oName', 'Chennai')]
# [('pName', 'sex or gender'), ('oName', 'male')]
# [('pName', 'country of citizenship'), ('oName', 'British India')]
# [('pName', 'country of citizenship'), ('oName', 'India')]
# [('pName', 'country of citizenship'), ('oName', 'Dominion of India')]
# [('pName', 'instance of'), ('oName', 'human')]
# [('pName', 'sibling'), ('oName', 'Prem Nawas')]
# [('pName', 'child'), ('oName', 'Shanawas')]
# [('pName', 'educated at'), ('oName', 'St. Berchmans College')]
# [('pName', 'given name'), ('oName', 'Prem')]
# 18

# %% [markdown]
# Final query for this task

# %%
# write your final query
queryString = """
SELECT DISTINCT ?actor ?actorName (COUNT(?tvseriesName) AS ?numseries)
WHERE {
    # ?tvseries wdt:P31 wd:Q5398426 ;
            sc:name ?tvseriesName .
   # ?tvseries wdt:P161 ?actor .
   # ?actor sc:name ?actorName .
}
GROUP BY ?actor ?actorName
ORDER BY DESC (?numseries)

LIMIT 50
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('actor', 'http://www.wikidata.org/entity/Q12042457'), ('actorName', 'Oldřich Vlach'), ('numseries', '26')]
# [('actor', 'http://www.wikidata.org/entity/Q10292775'), ('actorName', 'Guilherme Filipe'), ('numseries', '21')]
# [('actor', 'http://www.wikidata.org/entity/Q2058853'), ('actorName', 'Hernesta Derbez'), ('numseries', '21')]
# [('actor', 'http://www.wikidata.org/entity/Q741577'), ('actorName', 'Radoslav Brzobohatý'), ('numseries', '20')]
# [('actor', 'http://www.wikidata.org/entity/Q1683633'), ('actorName', 'Jaroslav Moučka'), ('numseries', '20')]
# [('actor', 'http://www.wikidata.org/entity/Q101209973'), ('actorName', 'Jiří Wohanka'), ('numseries', '20')]
# [('actor', 'http://www.wikidata.org/entity/Q11752586'), ('actorName', 'Ladislav Trojan'), ('numseries', '20')]
# [('actor', 'http://www.wikidata.org/entity/Q374447'), ('actorName', 'Sam Anderson'), ('numseries', '20')]
# [('actor', 'http://www.wikidata.org/entity/Q29525305'), ('actorName', 'Zdeněk Žák'), ('numseries', '19')]
# [('actor', 'http://www.wikidata.org/entity/Q12022899'), ('actorName', 'Jan Novotný'), ('numseries', '19')]
# [('actor', 'http://www.wikidata.org/entity/Q514606'), ('actorName', 'Jacqueline Andere'), ('numseries', '18')]
# [('actor', 'http://www.wikidata.org/entity/Q5179830'), ('actorName', 'Pavel Kříž'), ('numseries', '18')]
# [('actor', 'http://www.wikidata.org/entity/Q94741643'), ('actorName', 'Ludmilla Roubíková'), ('numseries', '18')]
# [('actor', 'http://www.wikidata.org/entity/Q228852'), ('actorName', 'Jane Lynch'), ('numseries', '18')]
# [('actor', 'http://www.wikidata.org/entity/Q8067970'), ('actorName', 'Zdeněk Srstka'), ('numseries', '18')]
# [('actor', 'http://www.wikidata.org/entity/Q386249'), ('actorName', 'Michael Gaston'), ('numseries', '18')]
# [('actor', 'http://www.wikidata.org/entity/Q2529744'), ('actorName', 'Jessica Tuck'), ('numseries', '18')]
# [('actor', 'http://www.wikidata.org/entity/Q149389'), ('actorName', 'Glória Pires'), ('numseries', '18')]
# [('actor', 'http://www.wikidata.org/entity/Q2885767'), ('actorName', 'Barry Livingston'), ('numseries', '18')]
# [('actor', 'http://www.wikidata.org/entity/Q463272'), ('actorName', 'Amparo Rivelles'), ('numseries', '18')]
# [('actor', 'http://www.wikidata.org/entity/Q464320'), ('actorName', 'Stephen Root'), ('numseries', '18')]
# [('actor', 'http://www.wikidata.org/entity/Q12022103'), ('actorName', 'Ivo Niederle'), ('numseries', '17')]
# [('actor', 'http://www.wikidata.org/entity/Q3505255'), ('actorName', 'Václav Vydra'), ('numseries', '17')]
# [('actor', 'http://www.wikidata.org/entity/Q290996'), ('actorName', 'Stella Zázvorková'), ('numseries', '17')]
# [('actor', 'http://www.wikidata.org/entity/Q453724'), ('actorName', 'John Billingsley'), ('numseries', '17')]
# [('actor', 'http://www.wikidata.org/entity/Q601743'), ('actorName', 'Victoria Ruffo'), ('numseries', '17')]
# [('actor', 'http://www.wikidata.org/entity/Q12023093'), ('actorName', 'Jan Skopeček'), ('numseries', '17')]
# [('actor', 'http://www.wikidata.org/entity/Q589015'), ('actorName', 'Glenn Morshower'), ('numseries', '17')]
# [('actor', 'http://www.wikidata.org/entity/Q11915750'), ('actorName', 'Vlastimil Zavřel'), ('numseries', '17')]
# [('actor', 'http://www.wikidata.org/entity/Q2064678'), ('actorName', 'Pavel Zedníček'), ('numseries', '17')]
# [('actor', 'http://www.wikidata.org/entity/Q2515601'), ('actorName', 'František Němec'), ('numseries', '17')]
# [('actor', 'http://www.wikidata.org/entity/Q512613'), ('actorName', 'Daniela Kolářová'), ('numseries', '17')]
# [('actor', 'http://www.wikidata.org/entity/Q1351441'), ('actorName', 'Eric Lange'), ('numseries', '17')]
# [('actor', 'http://www.wikidata.org/entity/Q12025679'), ('actorName', 'Jiří Štěpnička'), ('numseries', '17')]
# [('actor', 'http://www.wikidata.org/entity/Q498263'), ('actorName', 'Alan Ruck'), ('numseries', '17')]
# [('actor', 'http://www.wikidata.org/entity/Q176277'), ('actorName', 'Brett Cullen'), ('numseries', '16')]
# [('actor', 'http://www.wikidata.org/entity/Q95215073'), ('actorName', 'Vladimír Krška'), ('numseries', '16')]
# [('actor', 'http://www.wikidata.org/entity/Q1704337'), ('actorName', 'Josef Bláha'), ('numseries', '16')]
# [('actor', 'http://www.wikidata.org/entity/Q2940994'), ('actorName', 'Casey Sander'), ('numseries', '16')]
# [('actor', 'http://www.wikidata.org/entity/Q1417643'), ('actorName', 'Jiří Lábus'), ('numseries', '16')]
# [('actor', 'http://www.wikidata.org/entity/Q5357354'), ('actorName', 'Todd Stashwick'), ('numseries', '16')]
# [('actor', 'http://www.wikidata.org/entity/Q1309502'), ('actorName', 'Otakar Brousek, Sr.'), ('numseries', '16')]
# [('actor', 'http://www.wikidata.org/entity/Q12032940'), ('actorName', 'Lenka Termerová'), ('numseries', '16')]
# [('actor', 'http://www.wikidata.org/entity/Q12002390'), ('actorName', 'Věra Tichánková'), ('numseries', '16')]
# [('actor', 'http://www.wikidata.org/entity/Q1689754'), ('actorName', 'Jiří Bartoška'), ('numseries', '16')]
# [('actor', 'http://www.wikidata.org/entity/Q958791'), ('actorName', 'George Wyner'), ('numseries', '16')]
# [('actor', 'http://www.wikidata.org/entity/Q3858922'), ('actorName', 'Miroslav Táborský'), ('numseries', '16')]
# [('actor', 'http://www.wikidata.org/entity/Q12037784'), ('actorName', 'Mirko Musil'), ('numseries', '16')]
# [('actor', 'http://www.wikidata.org/entity/Q3193117'), ('actorName', 'Karen Maruyama'), ('numseries', '16')]
# [('actor', 'http://www.wikidata.org/entity/Q12023020'), ('actorName', 'Jan Přeučil'), ('numseries', '16')]
# 50

# %% [markdown]
# ## Task 4
# Check who is the actor who acted in more films while working on "How I met your mother" (the result set must be a list of triples actor/actress IRI, label and #films).

# %%
# write your queries
#actor/actress act in "How I met your mother"
#P161 cast member
queryString = """
SELECT DISTINCT ?film ?filmName ?actorName
WHERE {
   # ?film wdt:P161 ?actor .
   # ?film sc:name ?filmName .
   # ?actor sc:name ?actorName .
   FILTER REGEX(?filmName , "[Mm]other*")
   FILTER REGEX(?filmName , "[Hh]ow*")
}
LIMIT 10
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('film', 'http://www.wikidata.org/entity/Q147235'), ('filmName', 'How I Met Your Mother'), ('actorName', 'Annie Ilonzeh')]
# [('film', 'http://www.wikidata.org/entity/Q147235'), ('filmName', 'How I Met Your Mother'), ('actorName', 'Julianna Guill')]
# [('film', 'http://www.wikidata.org/entity/Q147235'), ('filmName', 'How I Met Your Mother'), ('actorName', 'Benjamin Koldyke')]
# [('film', 'http://www.wikidata.org/entity/Q147235'), ('filmName', 'How I Met Your Mother'), ('actorName', 'Nikki Griffin')]
# [('film', 'http://www.wikidata.org/entity/Q147235'), ('filmName', 'How I Met Your Mother'), ('actorName', 'John Cho')]
# [('film', 'http://www.wikidata.org/entity/Q147235'), ('filmName', 'How I Met Your Mother'), ('actorName', 'Mircea Monroe')]
# [('film', 'http://www.wikidata.org/entity/Q147235'), ('filmName', 'How I Met Your Mother'), ('actorName', 'Virginia Williams')]
# [('film', 'http://www.wikidata.org/entity/Q147235'), ('filmName', 'How I Met Your Mother'), ('actorName', 'Kate Micucci')]
# [('film', 'http://www.wikidata.org/entity/Q147235'), ('filmName', 'How I Met Your Mother'), ('actorName', 'Cobie Smulders')]
# [('film', 'http://www.wikidata.org/entity/Q147235'), ('filmName', 'How I Met Your Mother'), ('actorName', 'Ashley Williams')]
# 10

# %%
queryString = """
SELECT ?season ?seasonName (COUNT(?seasonName) AS ?numseasons)
WHERE 
{
    # ?tvseries wdt:P31 wd:Q5398426 ;
            sc:name ?tvseriesName .
    # ?season wdt:P179 ?tvseries ;
       sc:name ?seasonName .

   FILTER REGEX(?seasonName, "season*")   
}
GROUP BY ?season ?seasonName
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results

# %%
# Q147235 How I Met Your Mother
queryString = """
SELECT DISTINCT ?p ?pName #?oName
WHERE {
   wd:Q147235 ?p ?o .
   # ?p sc:name ?pName .
   # ?o sc:name ?oName .
}
LIMIT 50
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P161'), ('pName', 'cast member')]
# [('p', 'http://www.wikidata.org/prop/direct/P449'), ('pName', 'original broadcaster')]
# [('p', 'http://www.wikidata.org/prop/direct/P1411'), ('pName', 'nominated for')]
# [('p', 'http://www.wikidata.org/prop/direct/P86'), ('pName', 'composer')]
# [('p', 'http://www.wikidata.org/prop/direct/P136'), ('pName', 'genre')]
# [('p', 'http://www.wikidata.org/prop/direct/P364'), ('pName', 'original language of film or TV show')]
# [('p', 'http://www.wikidata.org/prop/direct/P2670'), ('pName', 'has parts of the class')]
# [('p', 'http://www.wikidata.org/prop/direct/P495'), ('pName', 'country of origin')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('p', 'http://www.wikidata.org/prop/direct/P840'), ('pName', 'narrative location')]
# [('p', 'http://www.wikidata.org/prop/direct/P437'), ('pName', 'distribution format')]
# [('p', 'http://www.wikidata.org/prop/direct/P750'), ('pName', 'distributed by')]
# [('p', 'http://www.wikidata.org/prop/direct/P2061'), ('pName', 'aspect ratio')]
# [('p', 'http://www.wikidata.org/prop/direct/P7501'), ('pName', 'audio system')]
# [('p', 'http://www.wikidata.org/prop/direct/P4312'), ('pName', 'camera setup')]
# [('p', 'http://www.wikidata.org/prop/direct/P272'), ('pName', 'production company')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part')]
# [('p', 'http://www.wikidata.org/prop/direct/P674'), ('pName', 'characters')]
# [('p', 'http://www.wikidata.org/prop/direct/P162'), ('pName', 'producer')]
# [('p', 'http://www.wikidata.org/prop/direct/P170'), ('pName', 'creator')]
# [('p', 'http://www.wikidata.org/prop/direct/P58'), ('pName', 'screenwriter')]
# [('p', 'http://www.wikidata.org/prop/direct/P725'), ('pName', 'voice actor')]
# [('p', 'http://www.wikidata.org/prop/direct/P138'), ('pName', 'named after')]
# [('p', 'http://www.wikidata.org/prop/direct/P166'), ('pName', 'award received')]
# [('p', 'http://www.wikidata.org/prop/direct/P910'), ('pName', "topic's main category")]
# [('p', 'http://www.wikidata.org/prop/direct/P1881'), ('pName', 'list of characters')]
# [('p', 'http://www.wikidata.org/prop/direct/P4969'), ('pName', 'derivative work')]
# [('p', 'http://www.wikidata.org/prop/direct/P1811'), ('pName', 'list of episodes')]
# [('p', 'http://www.wikidata.org/prop/direct/P1424'), ('pName', "topic's main template")]
# [('p', 'http://www.wikidata.org/prop/direct/P2438'), ('pName', 'narrator')]
# 30

# %%
# Q147235 How I Met Your Mother
queryString = """
SELECT DISTINCT ?actor ?actorName (COUNT(?film) AS ?numfilm)
WHERE {
   wd:Q147235 wdt:P161 ?actor .
   # ?actor sc:name ?actorName .
   # ?film wdt:P161 ?actor .
}
GROUP BY ?actor ?actorName
ORDER BY DESC (?numfilm)

LIMIT 30
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('actor', 'http://www.wikidata.org/entity/Q485310'), ('actorName', 'Neil Patrick Harris'), ('numfilm', '187')]
# [('actor', 'http://www.wikidata.org/entity/Q200566'), ('actorName', 'Cobie Smulders'), ('numfilm', '173')]
# [('actor', 'http://www.wikidata.org/entity/Q199927'), ('actorName', 'Alyson Hannigan'), ('numfilm', '170')]
# [('actor', 'http://www.wikidata.org/entity/Q202304'), ('actorName', 'Jason Segel'), ('numfilm', '170')]
# [('actor', 'http://www.wikidata.org/entity/Q223455'), ('actorName', 'Josh Radnor'), ('numfilm', '155')]
# [('actor', 'http://www.wikidata.org/entity/Q192165'), ('actorName', 'Danny Glover'), ('numfilm', '117')]
# [('actor', 'http://www.wikidata.org/entity/Q471018'), ('actorName', 'Ernie Hudson'), ('numfilm', '75')]
# [('actor', 'http://www.wikidata.org/entity/Q536437'), ('actorName', 'Edward Herrmann'), ('numfilm', '74')]
# [('actor', 'http://www.wikidata.org/entity/Q311271'), ('actorName', 'John Lithgow'), ('numfilm', '74')]
# [('actor', 'http://www.wikidata.org/entity/Q236189'), ('actorName', 'Judy Greer'), ('numfilm', '72')]
# [('actor', 'http://www.wikidata.org/entity/Q298777'), ('actorName', 'Michael York'), ('numfilm', '70')]
# [('actor', 'http://www.wikidata.org/entity/Q297128'), ('actorName', 'David Henrie'), ('numfilm', '67')]
# [('actor', 'http://www.wikidata.org/entity/Q186757'), ('actorName', 'Seth Green'), ('numfilm', '66')]
# [('actor', 'http://www.wikidata.org/entity/Q530646'), ('actorName', 'Ray Wise'), ('numfilm', '64')]
# [('actor', 'http://www.wikidata.org/entity/Q229914'), ('actorName', 'Lyndsy Fonseca'), ('numfilm', '63')]
# [('actor', 'http://www.wikidata.org/entity/Q309900'), ('actorName', 'Peter Gallagher'), ('numfilm', '62')]
# [('actor', 'http://www.wikidata.org/entity/Q1332676'), ('actorName', 'William Schallert'), ('numfilm', '61')]
# [('actor', 'http://www.wikidata.org/entity/Q545172'), ('actorName', 'Matt Frewer'), ('numfilm', '60')]
# [('actor', 'http://www.wikidata.org/entity/Q123849'), ('actorName', 'Jane Seymour'), ('numfilm', '60')]
# [('actor', 'http://www.wikidata.org/entity/Q207506'), ('actorName', 'Kyle MacLachlan'), ('numfilm', '54')]
# [('actor', 'http://www.wikidata.org/entity/Q888178'), ('actorName', 'Bob Odenkirk'), ('numfilm', '54')]
# [('actor', 'http://www.wikidata.org/entity/Q199929'), ('actorName', 'Jennifer Morrison'), ('numfilm', '53')]
# [('actor', 'http://www.wikidata.org/entity/Q23547'), ('actorName', 'Bryan Cranston'), ('numfilm', '52')]
# [('actor', 'http://www.wikidata.org/entity/Q3045427'), ('actorName', 'George Cheung'), ('numfilm', '50')]
# [('actor', 'http://www.wikidata.org/entity/Q233882'), ('actorName', 'Frances Conroy'), ('numfilm', '49')]
# [('actor', 'http://www.wikidata.org/entity/Q238117'), ('actorName', 'Christina Pickles'), ('numfilm', '48')]
# [('actor', 'http://www.wikidata.org/entity/Q312705'), ('actorName', 'John Cho'), ('numfilm', '48')]
# [('actor', 'http://www.wikidata.org/entity/Q234514'), ('actorName', 'Camryn Manheim'), ('numfilm', '47')]
# [('actor', 'http://www.wikidata.org/entity/Q1319539'), ('actorName', 'Thomas Lennon'), ('numfilm', '46')]
# [('actor', 'http://www.wikidata.org/entity/Q131332'), ('actorName', 'Amanda Peet'), ('numfilm', '46')]
# 30

# %% [markdown]
# Final query for this task

# %%
# write your final query
queryString = """
SELECT DISTINCT ?actor ?actorName (COUNT(?film) AS ?numfilm)
WHERE {
   wd:Q147235 wdt:P161 ?actor .
   # ?actor sc:name ?actorName .
   # ?film wdt:P161 ?actor .
}
GROUP BY ?actor ?actorName
ORDER BY DESC (?numfilm)

LIMIT 30
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('actor', 'http://www.wikidata.org/entity/Q485310'), ('actorName', 'Neil Patrick Harris'), ('numfilm', '187')]
# [('actor', 'http://www.wikidata.org/entity/Q200566'), ('actorName', 'Cobie Smulders'), ('numfilm', '173')]
# [('actor', 'http://www.wikidata.org/entity/Q199927'), ('actorName', 'Alyson Hannigan'), ('numfilm', '170')]
# [('actor', 'http://www.wikidata.org/entity/Q202304'), ('actorName', 'Jason Segel'), ('numfilm', '170')]
# [('actor', 'http://www.wikidata.org/entity/Q223455'), ('actorName', 'Josh Radnor'), ('numfilm', '155')]
# [('actor', 'http://www.wikidata.org/entity/Q192165'), ('actorName', 'Danny Glover'), ('numfilm', '117')]
# [('actor', 'http://www.wikidata.org/entity/Q471018'), ('actorName', 'Ernie Hudson'), ('numfilm', '75')]
# [('actor', 'http://www.wikidata.org/entity/Q536437'), ('actorName', 'Edward Herrmann'), ('numfilm', '74')]
# [('actor', 'http://www.wikidata.org/entity/Q311271'), ('actorName', 'John Lithgow'), ('numfilm', '74')]
# [('actor', 'http://www.wikidata.org/entity/Q236189'), ('actorName', 'Judy Greer'), ('numfilm', '72')]
# [('actor', 'http://www.wikidata.org/entity/Q298777'), ('actorName', 'Michael York'), ('numfilm', '70')]
# [('actor', 'http://www.wikidata.org/entity/Q297128'), ('actorName', 'David Henrie'), ('numfilm', '67')]
# [('actor', 'http://www.wikidata.org/entity/Q186757'), ('actorName', 'Seth Green'), ('numfilm', '66')]
# [('actor', 'http://www.wikidata.org/entity/Q530646'), ('actorName', 'Ray Wise'), ('numfilm', '64')]
# [('actor', 'http://www.wikidata.org/entity/Q229914'), ('actorName', 'Lyndsy Fonseca'), ('numfilm', '63')]
# [('actor', 'http://www.wikidata.org/entity/Q309900'), ('actorName', 'Peter Gallagher'), ('numfilm', '62')]
# [('actor', 'http://www.wikidata.org/entity/Q1332676'), ('actorName', 'William Schallert'), ('numfilm', '61')]
# [('actor', 'http://www.wikidata.org/entity/Q545172'), ('actorName', 'Matt Frewer'), ('numfilm', '60')]
# [('actor', 'http://www.wikidata.org/entity/Q123849'), ('actorName', 'Jane Seymour'), ('numfilm', '60')]
# [('actor', 'http://www.wikidata.org/entity/Q207506'), ('actorName', 'Kyle MacLachlan'), ('numfilm', '54')]
# [('actor', 'http://www.wikidata.org/entity/Q888178'), ('actorName', 'Bob Odenkirk'), ('numfilm', '54')]
# [('actor', 'http://www.wikidata.org/entity/Q199929'), ('actorName', 'Jennifer Morrison'), ('numfilm', '53')]
# [('actor', 'http://www.wikidata.org/entity/Q23547'), ('actorName', 'Bryan Cranston'), ('numfilm', '52')]
# [('actor', 'http://www.wikidata.org/entity/Q3045427'), ('actorName', 'George Cheung'), ('numfilm', '50')]
# [('actor', 'http://www.wikidata.org/entity/Q233882'), ('actorName', 'Frances Conroy'), ('numfilm', '49')]
# [('actor', 'http://www.wikidata.org/entity/Q238117'), ('actorName', 'Christina Pickles'), ('numfilm', '48')]
# [('actor', 'http://www.wikidata.org/entity/Q312705'), ('actorName', 'John Cho'), ('numfilm', '48')]
# [('actor', 'http://www.wikidata.org/entity/Q234514'), ('actorName', 'Camryn Manheim'), ('numfilm', '47')]
# [('actor', 'http://www.wikidata.org/entity/Q1319539'), ('actorName', 'Thomas Lennon'), ('numfilm', '46')]
# [('actor', 'http://www.wikidata.org/entity/Q131332'), ('actorName', 'Amanda Peet'), ('numfilm', '46')]
# 30

# %% [markdown]
# ## Task 5
# Compare HIMYM with the tv series "The Office (US)" in terms of number of seasons, episods and cast members (the result set must be two elements -one for each tv series- of tv series IRI, label, #seasons, #episodes and #cast members).

# %%
# write your queries
# Q147235 How I Met Your Mother number of films
# ?tvseries wdt:P31 wd:Q5398426 . instance of tvseries
queryString = """
SELECT DISTINCT 
WHERE {
   wd:Q147235 wdt:P161 ?actor .
   # ?actor sc:name ?actorName .
   # ?film wdt:P161 ?actor .
}
GROUP BY ?actor ?actorName
ORDER BY DESC (?numfilm)

LIMIT 30
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('actor', 'http://www.wikidata.org/entity/Q485310'), ('actorName', 'Neil Patrick Harris'), ('numfilm', '187')]
# [('actor', 'http://www.wikidata.org/entity/Q200566'), ('actorName', 'Cobie Smulders'), ('numfilm', '173')]
# [('actor', 'http://www.wikidata.org/entity/Q199927'), ('actorName', 'Alyson Hannigan'), ('numfilm', '170')]
# [('actor', 'http://www.wikidata.org/entity/Q202304'), ('actorName', 'Jason Segel'), ('numfilm', '170')]
# [('actor', 'http://www.wikidata.org/entity/Q223455'), ('actorName', 'Josh Radnor'), ('numfilm', '155')]
# [('actor', 'http://www.wikidata.org/entity/Q192165'), ('actorName', 'Danny Glover'), ('numfilm', '117')]
# [('actor', 'http://www.wikidata.org/entity/Q471018'), ('actorName', 'Ernie Hudson'), ('numfilm', '75')]
# [('actor', 'http://www.wikidata.org/entity/Q536437'), ('actorName', 'Edward Herrmann'), ('numfilm', '74')]
# [('actor', 'http://www.wikidata.org/entity/Q311271'), ('actorName', 'John Lithgow'), ('numfilm', '74')]
# [('actor', 'http://www.wikidata.org/entity/Q236189'), ('actorName', 'Judy Greer'), ('numfilm', '72')]
# [('actor', 'http://www.wikidata.org/entity/Q298777'), ('actorName', 'Michael York'), ('numfilm', '70')]
# [('actor', 'http://www.wikidata.org/entity/Q297128'), ('actorName', 'David Henrie'), ('numfilm', '67')]
# [('actor', 'http://www.wikidata.org/entity/Q186757'), ('actorName', 'Seth Green'), ('numfilm', '66')]
# [('actor', 'http://www.wikidata.org/entity/Q530646'), ('actorName', 'Ray Wise'), ('numfilm', '64')]
# [('actor', 'http://www.wikidata.org/entity/Q229914'), ('actorName', 'Lyndsy Fonseca'), ('numfilm', '63')]
# [('actor', 'http://www.wikidata.org/entity/Q309900'), ('actorName', 'Peter Gallagher'), ('numfilm', '62')]
# [('actor', 'http://www.wikidata.org/entity/Q1332676'), ('actorName', 'William Schallert'), ('numfilm', '61')]
# [('actor', 'http://www.wikidata.org/entity/Q545172'), ('actorName', 'Matt Frewer'), ('numfilm', '60')]
# [('actor', 'http://www.wikidata.org/entity/Q123849'), ('actorName', 'Jane Seymour'), ('numfilm', '60')]
# [('actor', 'http://www.wikidata.org/entity/Q207506'), ('actorName', 'Kyle MacLachlan'), ('numfilm', '54')]
# [('actor', 'http://www.wikidata.org/entity/Q888178'), ('actorName', 'Bob Odenkirk'), ('numfilm', '54')]
# [('actor', 'http://www.wikidata.org/entity/Q199929'), ('actorName', 'Jennifer Morrison'), ('numfilm', '53')]
# [('actor', 'http://www.wikidata.org/entity/Q23547'), ('actorName', 'Bryan Cranston'), ('numfilm', '52')]
# [('actor', 'http://www.wikidata.org/entity/Q3045427'), ('actorName', 'George Cheung'), ('numfilm', '50')]
# [('actor', 'http://www.wikidata.org/entity/Q233882'), ('actorName', 'Frances Conroy'), ('numfilm', '49')]
# [('actor', 'http://www.wikidata.org/entity/Q238117'), ('actorName', 'Christina Pickles'), ('numfilm', '48')]
# [('actor', 'http://www.wikidata.org/entity/Q312705'), ('actorName', 'John Cho'), ('numfilm', '48')]
# [('actor', 'http://www.wikidata.org/entity/Q234514'), ('actorName', 'Camryn Manheim'), ('numfilm', '47')]
# [('actor', 'http://www.wikidata.org/entity/Q1319539'), ('actorName', 'Thomas Lennon'), ('numfilm', '46')]
# [('actor', 'http://www.wikidata.org/entity/Q131332'), ('actorName', 'Amanda Peet'), ('numfilm', '46')]
# 30

# %%
#Q5398426 tvseries
queryString = """
SELECT DISTINCT ?tvseries ?tvseriesName
WHERE {
   # ?tvseries wdt:P31 wd:Q5398426 .
   # ?tvseries sc:name ?tvseriesName .
   FILTER REGEX(?tvseriesName , "[Oo]ffice*")
}
LIMIT 10
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('tvseries', 'http://www.wikidata.org/entity/Q28419054'), ('tvseriesName', 'Radiant Office')]
# [('tvseries', 'http://www.wikidata.org/entity/Q23829'), ('tvseriesName', 'The Office')]
# [('tvseries', 'http://www.wikidata.org/entity/Q23831'), ('tvseriesName', 'The Office')]
# [('tvseries', 'http://www.wikidata.org/entity/Q6532522'), ('tvseriesName', "Let's Play Post Office")]
# [('tvseries', 'http://www.wikidata.org/entity/Q7079129'), ('tvseriesName', 'Office Office')]
# [('tvseries', 'http://www.wikidata.org/entity/Q65043588'), ('tvseriesName', 'The Office')]
# [('tvseries', 'http://www.wikidata.org/entity/Q5759839'), ('tvseriesName', 'Office Girls')]
# [('tvseries', 'http://www.wikidata.org/entity/Q6928472'), ('tvseriesName', 'Mr. Box Office')]
# [('tvseries', 'http://www.wikidata.org/entity/Q6402787'), ('tvseriesName', 'Queen of the Office')]
# [('tvseries', 'http://www.wikidata.org/entity/Q7764423'), ('tvseriesName', 'The Singing Office')]
# 10

# %%
#P495 country of origin
queryString = """
SELECT DISTINCT ?p1 ?p1Name ?o1Name #?p2Name ?o2Name
WHERE {
   wd:Q23829 ?p1 ?o1 .
   wd:Q23831 ?p2 ?o2 .
   # ?p1 sc:name ?p1Name .
   # ?o1 sc:name ?o1Name .
    # ?p2 sc:name ?p2Name .
   # ?o2 sc:name ?o2Name .
   
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p1', 'http://www.wikidata.org/prop/direct/P136'), ('p1Name', 'genre'), ('o1Name', 'sitcom')]
# [('p1', 'http://www.wikidata.org/prop/direct/P136'), ('p1Name', 'genre'), ('o1Name', 'mockumentary')]
# [('p1', 'http://www.wikidata.org/prop/direct/P1552'), ('p1Name', 'has quality'), ('o1Name', 'breaking the fourth wall')]
# [('p1', 'http://www.wikidata.org/prop/direct/P161'), ('p1Name', 'cast member'), ('o1Name', 'Patrick Baladi')]
# [('p1', 'http://www.wikidata.org/prop/direct/P161'), ('p1Name', 'cast member'), ('o1Name', 'Ralph Ineson')]
# [('p1', 'http://www.wikidata.org/prop/direct/P161'), ('p1Name', 'cast member'), ('o1Name', 'Ricky Gervais')]
# [('p1', 'http://www.wikidata.org/prop/direct/P161'), ('p1Name', 'cast member'), ('o1Name', 'Martin Freeman')]
# [('p1', 'http://www.wikidata.org/prop/direct/P161'), ('p1Name', 'cast member'), ('o1Name', 'Lucy Davis')]
# [('p1', 'http://www.wikidata.org/prop/direct/P161'), ('p1Name', 'cast member'), ('o1Name', 'Oliver Chris')]
# [('p1', 'http://www.wikidata.org/prop/direct/P161'), ('p1Name', 'cast member'), ('o1Name', 'Stirling Gallacher')]
# [('p1', 'http://www.wikidata.org/prop/direct/P161'), ('p1Name', 'cast member'), ('o1Name', 'Mackenzie Crook')]
# [('p1', 'http://www.wikidata.org/prop/direct/P161'), ('p1Name', 'cast member'), ('o1Name', 'Stacey Roca')]
# [('p1', 'http://www.wikidata.org/prop/direct/P170'), ('p1Name', 'creator'), ('o1Name', 'Ricky Gervais')]
# [('p1', 'http://www.wikidata.org/prop/direct/P170'), ('p1Name', 'creator'), ('o1Name', 'Stephen Merchant')]
# [('p1', 'http://www.wikidata.org/prop/direct/P1811'), ('p1Name', 'list of episodes'), ('o1Name', 'list of The Office episodes')]
# [('p1', 'http://www.wikidata.org/prop/direct/P1889'), ('p1Name', 'different from'), ('o1Name', 'The Office')]
# [('p1', 'http://www.wikidata.org/prop/direct/P2061'), ('p1Name', 'aspect ratio'), ('o1Name', '16:9 aspect ratio')]
# [('p1', 'http://www.wikidata.org/prop/direct/P2670'), ('p1Name', 'has parts of the class'), ('o1Name', 'two-part episode')]
# [('p1', 'http://www.wikidata.org/prop/direct/P2747'), ('p1Name', 'Filmiroda rating'), ('o1Name', 'Category II')]
# [('p1', 'http://www.wikidata.org/prop/direct/P31'), ('p1Name', 'instance of'), ('o1Name', 'television series')]
# [('p1', 'http://www.wikidata.org/prop/direct/P364'), ('p1Name', 'original language of film or TV show'), ('o1Name', 'English')]
# [('p1', 'http://www.wikidata.org/prop/direct/P437'), ('p1Name', 'distribution format'), ('o1Name', 'video on demand')]
# [('p1', 'http://www.wikidata.org/prop/direct/P449'), ('p1Name', 'original broadcaster'), ('o1Name', 'BBC Two')]
# [('p1', 'http://www.wikidata.org/prop/direct/P449'), ('p1Name', 'original broadcaster'), ('o1Name', 'BBC One')]
# [('p1', 'http://www.wikidata.org/prop/direct/P495'), ('p1Name', 'country of origin'), ('o1Name', 'United Kingdom')]
# [('p1', 'http://www.wikidata.org/prop/direct/P4969'), ('p1Name', 'derivative work'), ('o1Name', 'The Office')]
# [('p1', 'http://www.wikidata.org/prop/direct/P4969'), ('p1Name', 'derivative work'), ('o1Name', 'Kontoret')]
# [('p1', 'http://www.wikidata.org/prop/direct/P4969'), ('p1Name', 'derivative work'), ('o1Name', 'Stromberg')]
# [('p1', 'http://www.wikidata.org/prop/direct/P4969'), ('p1Name', 'derivative work'), ('o1Name', 'La Job')]
# [('p1', 'http://www.wikidata.org/prop/direct/P4969'), ('p1Name', 'derivative work'), ('o1Name', 'La Ofis')]
# [('p1', 'http://www.wikidata.org/prop/direct/P4969'), ('p1Name', 'derivative work'), ('o1Name', 'HaMisrad')]
# [('p1', 'http://www.wikidata.org/prop/direct/P4969'), ('p1Name', 'derivative work'), ('o1Name', 'Le Bureau')]
# [('p1', 'http://www.wikidata.org/prop/direct/P750'), ('p1Name', 'distributed by'), ('o1Name', 'Netflix')]
# [('p1', 'http://www.wikidata.org/prop/direct/P750'), ('p1Name', 'distributed by'), ('o1Name', 'Hulu')]
# [('p1', 'http://www.wikidata.org/prop/direct/P8411'), ('p1Name', 'set in environment'), ('o1Name', 'island')]
# [('p1', 'http://www.wikidata.org/prop/direct/P910'), ('p1Name', "topic's main category"), ('o1Name', 'Category:The Office (British TV series)')]
# 36

# %%
#P495 country of origin
queryString = """
SELECT DISTINCT ?country1 ?country1Name ?country2 ?country2Name
WHERE {
   wd:Q23829 wdt:P495 ?country1 .
   wd:Q23831 wdt:P495 ?country2 .
   # ?country1 sc:name ?country1Name .
   # ?country2 sc:name ?country2Name .
   
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('country1', 'http://www.wikidata.org/entity/Q145'), ('country1Name', 'United Kingdom'), ('country2', 'http://www.wikidata.org/entity/Q30'), ('country2Name', 'United States of America')]
# 1

# %%
queryString = """
SELECT DISTINCT wd:Q23831 ?theofficeName ?numseaonOffice ?numepisodeoffice ?numofficeactor
WHERE
{              
    {
        SELECT DISTINCT ?theofficeName (COUNT(?officeseasonName) AS ?numseaonOffice)  
        WHERE
        {
            wd:Q23831 sc:name ?theofficeName .
            # ?officeseason wdt:P179 wd:Q23831 ;
               sc:name ?officeseasonName .
           FILTER REGEX(?officeseasonName, "season*") 
        }
       GROUP BY ?theofficeName
    }

    {
        SELECT DISTINCT ?theofficeName (COUNT(?officeepisodeName) AS ?numepisodeoffice)  
        WHERE
        {
            wd:Q23831 sc:name ?theofficeName .
            # ?officeepisode wdt:P179 wd:Q23831 ;
               sc:name ?officeepisodeName .
        }
       GROUP BY ?theofficeName
   }


   {
       SELECT DISTINCT ?theofficeName (COUNT(?officeactorName) AS ?numofficeactor)  
        WHERE
        {
            wd:Q23831 sc:name ?theofficeName .
            wd:Q23831 wdt:P161 ?officeactor .
            # ?officeactor sc:name ?officeactorName .

        }
       GROUP BY ?theofficeName
   }
}
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('callret-0', 'http://www.wikidata.org/entity/Q23831'), ('theofficeName', 'The Office'), ('numseaonOffice', '9'), ('numepisodeoffice', '226'), ('numofficeactor', '25')]
# 1

# %%
queryString = """
SELECT DISTINCT wd:Q147235 ?himymName ?numseaonHimym ?numepisodeHimym ?numhimymactor
WHERE
{ 
    {
        SELECT DISTINCT ?himymName (COUNT(?himymseasonName) AS ?numseaonHimym)  
        WHERE
        {
            wd:Q147235 sc:name ?himymName .
            # ?himymseason wdt:P179  wd:Q23831 ; 
                   sc:name ?himymseasonName .
            FILTER REGEX(?himymseasonName, "season*") 
        }
       GROUP BY ?himymName
   }
    {
        SELECT DISTINCT ?himymName (COUNT(?himymepisodeName) AS ?numepisodeHimym)  
        WHERE
        {
            wd:Q147235 sc:name ?himymName .
            # ?himymepisode wdt:P179  wd:Q23831 ; 
                   sc:name ?himymepisodeName .
        }
       GROUP BY ?himymName
   }


   {
       SELECT DISTINCT ?himymName (COUNT(?himymactorName) AS ?numhimymactor)  
        WHERE
        {
            wd:Q147235 sc:name ?himymName .
            wd:Q147235 wdt:P161 ?himymactor .
            # ?himymactor sc:name ?himymactorName .

        }
       GROUP BY ?himymName
   }

}

"""
print("Results")
x=run_query(queryString)
# Out:
# Results
# [('callret-0', 'http://www.wikidata.org/entity/Q147235'), ('himymName', 'How I Met Your Mother'), ('numseaonHimym', '9'), ('numepisodeHimym', '226'), ('numhimymactor', '480')]
# 1

# %%
#compare number of seasons
# wd:Q23831 the tv series "The Office (US)"
# wd:Q147235 How I Met Your Mother (HIMYM)
queryString = """
SELECT DISTINCT 
wd:Q23831 ?theofficeName ?numseaonOffice ?numepisodeoffice ?numofficeactor
wd:Q147235 ?himymName ?numseaonHimym ?numepisodeHimym ?numhimymactor
WHERE 
{
        {              
            {
                SELECT DISTINCT ?theofficeName (COUNT(?officeseasonName) AS ?numseaonOffice)  
                WHERE
                {
                    wd:Q23831 sc:name ?theofficeName .
                    # ?officeseason wdt:P179 wd:Q23831 ;
                       sc:name ?officeseasonName .
                   FILTER REGEX(?officeseasonName, "season*") 
                }
               GROUP BY ?theofficeName
            }

            {
                SELECT DISTINCT ?theofficeName (COUNT(?officeepisodeName) AS ?numepisodeoffice)  
                WHERE
                {
                    wd:Q23831 sc:name ?theofficeName .
                    # ?officeepisode wdt:P179 wd:Q23831 ;
                       sc:name ?officeepisodeName .
                }
               GROUP BY ?theofficeName
           }


           {
               SELECT DISTINCT ?theofficeName (COUNT(?officeactorName) AS ?numofficeactor)  
                WHERE
                {
                    wd:Q23831 sc:name ?theofficeName .
                    wd:Q23831 wdt:P161 ?officeactor .
                    # ?officeactor sc:name ?officeactorName .

                }
               GROUP BY ?theofficeName
           }
        }

        { 
            {
                SELECT DISTINCT ?himymName (COUNT(?himymseasonName) AS ?numseaonHimym)  
                WHERE
                {
                    wd:Q147235 sc:name ?himymName .
                    # ?himymseason wdt:P179  wd:Q23831 ; 
                           sc:name ?himymseasonName .
                    FILTER REGEX(?himymseasonName, "season*") 
                }
               GROUP BY ?himymName
           }
            {
                SELECT DISTINCT ?himymName (COUNT(?himymepisodeName) AS ?numepisodeHimym)  
                WHERE
                {
                    wd:Q147235 sc:name ?himymName .
                    # ?himymepisode wdt:P179  wd:Q23831 ; 
                           sc:name ?himymepisodeName .
                }
               GROUP BY ?himymName
           }


           {
               SELECT DISTINCT ?himymName (COUNT(?himymactorName) AS ?numhimymactor)  
                WHERE
                {
                    wd:Q147235 sc:name ?himymName .
                    wd:Q147235 wdt:P161 ?himymactor .
                    # ?himymactor sc:name ?himymactorName .

                }
               GROUP BY ?himymName
           }

        }


}


LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('callret-0', 'http://www.wikidata.org/entity/Q23831'), ('theofficeName', 'The Office'), ('numseaonOffice', '9'), ('numepisodeoffice', '226'), ('numofficeactor', '25'), ('callret-5', 'http://www.wikidata.org/entity/Q147235'), ('himymName', 'How I Met Your Mother'), ('numseaonHimym', '9'), ('numepisodeHimym', '226'), ('numhimymactor', '480')]
# 1

# %% [markdown]
# Final query for this task

# %%
# write your final query
queryString = """
SELECT DISTINCT 
wd:Q23831 ?theofficeName ?numseaonOffice ?numepisodeoffice ?numofficeactor
wd:Q147235 ?himymName ?numseaonHimym ?numepisodeHimym ?numhimymactor
WHERE 
{
        {              
            {
                SELECT DISTINCT ?theofficeName (COUNT(?officeseasonName) AS ?numseaonOffice)  
                WHERE
                {
                    wd:Q23831 sc:name ?theofficeName .
                    # ?officeseason wdt:P179 wd:Q23831 ;
                       sc:name ?officeseasonName .
                   FILTER REGEX(?officeseasonName, "season*") 
                }
               GROUP BY ?theofficeName
            }

            {
                SELECT DISTINCT ?theofficeName (COUNT(?officeepisodeName) AS ?numepisodeoffice)  
                WHERE
                {
                    wd:Q23831 sc:name ?theofficeName .
                    # ?officeepisode wdt:P179 wd:Q23831 ;
                       sc:name ?officeepisodeName .
                }
               GROUP BY ?theofficeName
           }


           {
               SELECT DISTINCT ?theofficeName (COUNT(?officeactorName) AS ?numofficeactor)  
                WHERE
                {
                    wd:Q23831 sc:name ?theofficeName .
                    wd:Q23831 wdt:P161 ?officeactor .
                    # ?officeactor sc:name ?officeactorName .

                }
               GROUP BY ?theofficeName
           }
        }

        { 
            {
                SELECT DISTINCT ?himymName (COUNT(?himymseasonName) AS ?numseaonHimym)  
                WHERE
                {
                    wd:Q147235 sc:name ?himymName .
                    # ?himymseason wdt:P179  wd:Q23831 ; 
                           sc:name ?himymseasonName .
                    FILTER REGEX(?himymseasonName, "season*") 
                }
               GROUP BY ?himymName
           }
            {
                SELECT DISTINCT ?himymName (COUNT(?himymepisodeName) AS ?numepisodeHimym)  
                WHERE
                {
                    wd:Q147235 sc:name ?himymName .
                    # ?himymepisode wdt:P179  wd:Q23831 ; 
                           sc:name ?himymepisodeName .
                }
               GROUP BY ?himymName
           }


           {
               SELECT DISTINCT ?himymName (COUNT(?himymactorName) AS ?numhimymactor)  
                WHERE
                {
                    wd:Q147235 sc:name ?himymName .
                    wd:Q147235 wdt:P161 ?himymactor .
                    # ?himymactor sc:name ?himymactorName .

                }
               GROUP BY ?himymName
           }

        }


}


LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('callret-0', 'http://www.wikidata.org/entity/Q23831'), ('theofficeName', 'The Office'), ('numseaonOffice', '9'), ('numepisodeoffice', '226'), ('numofficeactor', '25'), ('callret-5', 'http://www.wikidata.org/entity/Q147235'), ('himymName', 'How I Met Your Mother'), ('numseaonHimym', '9'), ('numepisodeHimym', '226'), ('numhimymactor', '480')]
# 1

# %% [markdown]
# ## Task 6
# Return how many of the actors who are members of the cast of the tv series have [Kavin Bacon number](https://en.wikipedia.org/wiki/Six_Degrees_of_Kevin_Bacon#:~:text=Kevin%20Bacon%20himself%20has%20a,Bacon%20number%20is%20N%2B1.) equal to 2 (the result set must be a list of couples actor/actress IRI and label).

# %%
# write your queries
queryString = """
SELECT DISTINCT ?actor ?actorName
WHERE {
    # ?tvseries wdt:P31 wd:Q5398426 ;
            sc:name ?tvseriesName.
    # ?tvseries wdt:P161 ?actor .
    # ?actor sc:name ?actorName .
    FILTER REGEX(?actorName, "Kevin Bacon")
}
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('actor', 'http://www.wikidata.org/entity/Q3454165'), ('actorName', 'Kevin Bacon')]
# 1

# %%
#Q3454165 Kevin Bacon
queryString = """
SELECT DISTINCT  (COUNT(?actorBaconnum2Name) AS ?howmany)
WHERE 
{
    # ?tvseries1 wdt:P161 wd:Q3454165 .
    # ?tvseries2 wdt:P161 wd:Q3454165 .
    # ?tvseries1 sc:name ?tvseries1Name .
    # ?tvseries1 wdt:P161 ?actorBaconnum1 .
    # ?tvseries2 wdt:P161 ?actorBaconnum1 .
    # ?tvseries2 wdt:P161 ?actorBaconnum2 .
    # ?tvseries1 sc:name ?tvseries1Name .
    # ?tvseries2 sc:name ?tvseries2Name .
    # ?actorBaconnum1 sc:name ?actorBaconnum1Name .
    # ?actorBaconnum2 sc:name ?actorBaconnum2Name .
    FILTER (?tvseries1 != ?tvseries2)
    FILTER (?actorBaconnum1Name != ?actorBaconnum2Name)

} 

LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('howmany', '67568')]
# 1

# %% [markdown]
# Final query for this task

# %%
# write your final query
queryString = """
SELECT DISTINCT  (COUNT(?actorBaconnum2Name) AS ?howmany)
WHERE 
{
    # ?tvseries1 wdt:P161 wd:Q3454165 .
    # ?tvseries2 wdt:P161 wd:Q3454165 .
    # ?tvseries1 sc:name ?tvseries1Name .
    # ?tvseries1 wdt:P161 ?actorBaconnum1 .
    # ?tvseries2 wdt:P161 ?actorBaconnum1 .
    # ?tvseries2 wdt:P161 ?actorBaconnum2 .
    # ?tvseries1 sc:name ?tvseries1Name .
    # ?tvseries2 sc:name ?tvseries2Name .
    # ?actorBaconnum1 sc:name ?actorBaconnum1Name .
    # ?actorBaconnum2 sc:name ?actorBaconnum2Name .
    FILTER (?tvseries1 != ?tvseries2)
    FILTER (?actorBaconnum1Name != ?actorBaconnum2Name)

} 

LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('howmany', '67568')]
# 1

# %% [markdown]
# ## Task 7
# Consider the actors who are members of the cast of HIMYM. Amongst the tv series which these actors acted return only those which received more than 2 awards (the result set must be triples of tv series IRI, label, #awards won).

# %%
# write your queries
queryString = """
SELECT DISTINCT ?tvseries ?tvseriesName
WHERE 
{
    wd:Q147235 wdt:P161 ?actor .
    # ?actor sc:name ?actorName .
    # ?tvseries wdt:P161 ?actor .
    # ?tvseries sc:name ?tvseriesName .
} 

LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('tvseries', 'http://www.wikidata.org/entity/Q500769'), ('tvseriesName', 'Freaks and Geeks')]
# [('tvseries', 'http://www.wikidata.org/entity/Q17049828'), ('tvseriesName', 'Bad Samaritans')]
# [('tvseries', 'http://www.wikidata.org/entity/Q377923'), ('tvseriesName', 'Some Came Running')]
# [('tvseries', 'http://www.wikidata.org/entity/Q15072819'), ('tvseriesName', 'Halt and Catch Fire')]
# [('tvseries', 'http://www.wikidata.org/entity/Q17627616'), ('tvseriesName', 'Miss Meadows')]
# [('tvseries', 'http://www.wikidata.org/entity/Q17635617'), ('tvseriesName', 'Nantucket')]
# [('tvseries', 'http://www.wikidata.org/entity/Q1197932'), ('tvseriesName', 'Magic Mike')]
# [('tvseries', 'http://www.wikidata.org/entity/Q18151386'), ('tvseriesName', 'Kirby Buckets')]
# [('tvseries', 'http://www.wikidata.org/entity/Q22908690'), ('tvseriesName', 'The Good Place')]
# [('tvseries', 'http://www.wikidata.org/entity/Q210676'), ('tvseriesName', 'Nashville')]
# [('tvseries', 'http://www.wikidata.org/entity/Q1607657'), ('tvseriesName', 'Under Wraps')]
# [('tvseries', 'http://www.wikidata.org/entity/Q1808437'), ('tvseriesName', 'The Jerk')]
# [('tvseries', 'http://www.wikidata.org/entity/Q23558'), ('tvseriesName', 'House')]
# [('tvseries', 'http://www.wikidata.org/entity/Q487978'), ('tvseriesName', 'Austin Powers: The Spy Who Shagged Me')]
# [('tvseries', 'http://www.wikidata.org/entity/Q498109'), ('tvseriesName', 'Rush Hour 3')]
# [('tvseries', 'http://www.wikidata.org/entity/Q498569'), ('tvseriesName', 'Rules of Engagement')]
# [('tvseries', 'http://www.wikidata.org/entity/Q500093'), ('tvseriesName', 'Legally Blonde')]
# [('tvseries', 'http://www.wikidata.org/entity/Q500460'), ('tvseriesName', 'Evolution')]
# [('tvseries', 'http://www.wikidata.org/entity/Q531675'), ('tvseriesName', 'Angel Eyes')]
# [('tvseries', 'http://www.wikidata.org/entity/Q547863'), ('tvseriesName', 'Montana Sky')]
# 20

# %%
queryString = """
SELECT DISTINCT ?awardName
WHERE 
{
    wd:Q147235 wdt:P166 ?award .
    # ?award sc:name ?awardName .
} 
GROUP BY ?tvseriesName

LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('awardName', 'Primetime Emmy Award for Outstanding Art Direction for a Contemporary Program')]
# [('awardName', "Critics' Choice Television Award for Best Supporting Actor in a Comedy Series")]
# [('awardName', 'International TV Audience Award for Best Comedy TV Series')]
# [('awardName', 'Primetime Emmy Award for Outstanding Cinematography for a Multi-Camera Series')]
# [('awardName', 'Primetime Emmy Award for Outstanding Multi-Camera Picture Editing for a Comedy Series')]
# [('awardName', 'Primetime Emmy Award for Outstanding Single-Camera Picture Editing for a Comedy Series')]
# [('awardName', 'Streamy Awards')]
# 7

# %%
#wd:Q147235 HIMYM 
#P166 award received
queryString = """
SELECT DISTINCT ?tvseries ?tvseriesName (COUNT(?awardName) AS ?numaward)
WHERE 
{
    wd:Q147235 wdt:P161 ?actor .
    # ?actor sc:name ?actorName .
    
    # ?tvseries wdt:P161 ?actor ;
            wdt:P31 wd:Q5398426 ;
            sc:name ?tvseriesName ;
            wdt:P166 ?award .
    # ?award sc:name ?awardName .
    
} 
GROUP BY ?tvseries ?tvseriesName ?actorName
ORDER BY DESC (?numaward)

LIMIT 30
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('tvseries', 'http://www.wikidata.org/entity/Q23628'), ('tvseriesName', 'The Sopranos'), ('numaward', '22')]
# [('tvseries', 'http://www.wikidata.org/entity/Q1079'), ('tvseriesName', 'Breaking Bad'), ('numaward', '21')]
# [('tvseries', 'http://www.wikidata.org/entity/Q1132439'), ('tvseriesName', 'The Practice'), ('numaward', '12')]
# [('tvseries', 'http://www.wikidata.org/entity/Q16756'), ('tvseriesName', 'Modern Family'), ('numaward', '11')]
# [('tvseries', 'http://www.wikidata.org/entity/Q8539'), ('tvseriesName', 'The Big Bang Theory'), ('numaward', '10')]
# [('tvseries', 'http://www.wikidata.org/entity/Q79784'), ('tvseriesName', 'Friends'), ('numaward', '10')]
# [('tvseries', 'http://www.wikidata.org/entity/Q1136370'), ('tvseriesName', 'General Hospital'), ('numaward', '10')]
# [('tvseries', 'http://www.wikidata.org/entity/Q244803'), ('tvseriesName', 'Ally McBeal'), ('numaward', '9')]
# [('tvseries', 'http://www.wikidata.org/entity/Q438406'), ('tvseriesName', "Grey's Anatomy"), ('numaward', '8')]
# [('tvseries', 'http://www.wikidata.org/entity/Q1030713'), ('tvseriesName', 'Another World'), ('numaward', '8')]
# [('tvseries', 'http://www.wikidata.org/entity/Q1068952'), ('tvseriesName', 'St. Elsewhere'), ('numaward', '8')]
# [('tvseries', 'http://www.wikidata.org/entity/Q147235'), ('tvseriesName', 'How I Met Your Mother'), ('numaward', '7')]
# [('tvseries', 'http://www.wikidata.org/entity/Q34659'), ('tvseriesName', 'My Name Is Earl'), ('numaward', '7')]
# [('tvseries', 'http://www.wikidata.org/entity/Q186219'), ('tvseriesName', 'True Blood'), ('numaward', '7')]
# [('tvseries', 'http://www.wikidata.org/entity/Q117396'), ('tvseriesName', 'CSI: Vegas'), ('numaward', '6')]
# [('tvseries', 'http://www.wikidata.org/entity/Q2085'), ('tvseriesName', 'Twin Peaks'), ('numaward', '6')]
# [('tvseries', 'http://www.wikidata.org/entity/Q7099650'), ('tvseriesName', 'Orange Is the New Black'), ('numaward', '6')]
# [('tvseries', 'http://www.wikidata.org/entity/Q1168760'), ('tvseriesName', 'Upstairs, Downstairs'), ('numaward', '5')]
# [('tvseries', 'http://www.wikidata.org/entity/Q833322'), ('tvseriesName', 'Murder, She Wrote'), ('numaward', '4')]
# [('tvseries', 'http://www.wikidata.org/entity/Q19570'), ('tvseriesName', 'The Good Wife'), ('numaward', '3')]
# [('tvseries', 'http://www.wikidata.org/entity/Q232737'), ('tvseriesName', 'The Walking Dead'), ('numaward', '3')]
# [('tvseries', 'http://www.wikidata.org/entity/Q30603704'), ('tvseriesName', 'Pose'), ('numaward', '3')]
# [('tvseries', 'http://www.wikidata.org/entity/Q1144624'), ('tvseriesName', 'Family Ties'), ('numaward', '3')]
# [('tvseries', 'http://www.wikidata.org/entity/Q7103920'), ('tvseriesName', 'Orphan Black'), ('numaward', '2')]
# [('tvseries', 'http://www.wikidata.org/entity/Q23609'), ('tvseriesName', 'Weeds'), ('numaward', '2')]
# [('tvseries', 'http://www.wikidata.org/entity/Q23594'), ('tvseriesName', 'Homeland'), ('numaward', '2')]
# [('tvseries', 'http://www.wikidata.org/entity/Q1122661'), ('tvseriesName', 'Project Runway'), ('numaward', '2')]
# [('tvseries', 'http://www.wikidata.org/entity/Q4525'), ('tvseriesName', 'NCIS'), ('numaward', '1')]
# [('tvseries', 'http://www.wikidata.org/entity/Q256527'), ('tvseriesName', 'Spin City'), ('numaward', '1')]
# [('tvseries', 'http://www.wikidata.org/entity/Q183513'), ('tvseriesName', 'Buffy the Vampire Slayer'), ('numaward', '1')]
# 30

# %% [markdown]
# Final query for this task

# %%
# write your final query
queryString = """
SELECT DISTINCT ?tvseries ?tvseriesName (COUNT(?awardName) AS ?numaward)
WHERE 
{
    wd:Q147235 wdt:P161 ?actor .
    # ?actor sc:name ?actorName .
    
    # ?tvseries wdt:P161 ?actor ;
            wdt:P31 wd:Q5398426 ;
            sc:name ?tvseriesName ;
            wdt:P166 ?award .
    # ?award sc:name ?awardName .
} 
GROUP BY ?tvseries ?tvseriesName ?actorName
HAVING (COUNT(?awardName) > 2)
ORDER BY DESC (?numaward)


LIMIT 30
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('tvseries', 'http://www.wikidata.org/entity/Q23628'), ('tvseriesName', 'The Sopranos'), ('numaward', '22')]
# [('tvseries', 'http://www.wikidata.org/entity/Q1079'), ('tvseriesName', 'Breaking Bad'), ('numaward', '21')]
# [('tvseries', 'http://www.wikidata.org/entity/Q1132439'), ('tvseriesName', 'The Practice'), ('numaward', '12')]
# [('tvseries', 'http://www.wikidata.org/entity/Q16756'), ('tvseriesName', 'Modern Family'), ('numaward', '11')]
# [('tvseries', 'http://www.wikidata.org/entity/Q8539'), ('tvseriesName', 'The Big Bang Theory'), ('numaward', '10')]
# [('tvseries', 'http://www.wikidata.org/entity/Q79784'), ('tvseriesName', 'Friends'), ('numaward', '10')]
# [('tvseries', 'http://www.wikidata.org/entity/Q1136370'), ('tvseriesName', 'General Hospital'), ('numaward', '10')]
# [('tvseries', 'http://www.wikidata.org/entity/Q244803'), ('tvseriesName', 'Ally McBeal'), ('numaward', '9')]
# [('tvseries', 'http://www.wikidata.org/entity/Q438406'), ('tvseriesName', "Grey's Anatomy"), ('numaward', '8')]
# [('tvseries', 'http://www.wikidata.org/entity/Q1030713'), ('tvseriesName', 'Another World'), ('numaward', '8')]
# [('tvseries', 'http://www.wikidata.org/entity/Q1068952'), ('tvseriesName', 'St. Elsewhere'), ('numaward', '8')]
# [('tvseries', 'http://www.wikidata.org/entity/Q147235'), ('tvseriesName', 'How I Met Your Mother'), ('numaward', '7')]
# [('tvseries', 'http://www.wikidata.org/entity/Q34659'), ('tvseriesName', 'My Name Is Earl'), ('numaward', '7')]
# [('tvseries', 'http://www.wikidata.org/entity/Q186219'), ('tvseriesName', 'True Blood'), ('numaward', '7')]
# [('tvseries', 'http://www.wikidata.org/entity/Q117396'), ('tvseriesName', 'CSI: Vegas'), ('numaward', '6')]
# [('tvseries', 'http://www.wikidata.org/entity/Q2085'), ('tvseriesName', 'Twin Peaks'), ('numaward', '6')]
# [('tvseries', 'http://www.wikidata.org/entity/Q7099650'), ('tvseriesName', 'Orange Is the New Black'), ('numaward', '6')]
# [('tvseries', 'http://www.wikidata.org/entity/Q1168760'), ('tvseriesName', 'Upstairs, Downstairs'), ('numaward', '5')]
# [('tvseries', 'http://www.wikidata.org/entity/Q833322'), ('tvseriesName', 'Murder, She Wrote'), ('numaward', '4')]
# [('tvseries', 'http://www.wikidata.org/entity/Q19570'), ('tvseriesName', 'The Good Wife'), ('numaward', '3')]
# [('tvseries', 'http://www.wikidata.org/entity/Q232737'), ('tvseriesName', 'The Walking Dead'), ('numaward', '3')]
# [('tvseries', 'http://www.wikidata.org/entity/Q30603704'), ('tvseriesName', 'Pose'), ('numaward', '3')]
# [('tvseries', 'http://www.wikidata.org/entity/Q1144624'), ('tvseriesName', 'Family Ties'), ('numaward', '3')]
# 23

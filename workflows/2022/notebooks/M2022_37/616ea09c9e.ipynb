# %% [markdown]
# # General instructions
#
# The goal of the project is to materialize a set of **exploratory workloads** over a real-world, large-scale,  open-domain KG: [WikiData](https://www.wikidata.org/wiki/Wikidata:Main_Page)
#
# An exploratory workload  is composed by a set of queries, where each query is related to the information obtained previously.
#
# An exploratory workload starts with a usually vague, open ended question, and does not assume the person issuing the workload has a clear understanding of the data contained in the target database or its structure.
#
# Remeber that:
#
# 1. All the queries must run in the python notebook
# 2. You can use classes and properties only if you find them via a SPARQL query that must be present in the notebook
# 3. You do not delete useless queries. Keep everything that is synthatically valid
#
# ```
# ?p <http://schema.org/name> ?name .
# ```
#
#     is the BGP returning a human-readable name of a property or a class in Wikidata.

# %%
## SETUP used later

from SPARQLWrapper import SPARQLWrapper, JSON


prefixString = """
##-616ea09c9e-##
PREFIX wd: <http://www.wikidata.org/entity/> 
PREFIX wdt: <http://www.wikidata.org/prop/direct/> 
PREFIX sc: <http://schema.org/>
"""

# select and construct queries
def run_query(queryString,verbose = True):
    to_run = prefixString + "\n" + queryString

    sparql = SPARQLWrapper("http://a256-gc1-03.srv.aau.dk:5820/sparql")
    sparql.setTimeout(300)
    sparql.setReturnFormat(JSON)
    sparql.setQuery(to_run)

    try :
        results = sparql.query()
        json_results = results.convert()
        if len(json_results['results']['bindings'])==0:
            print("Empty")
            return []
        array = []
        for bindings in json_results['results']['bindings']:
            app =  [ (var, value['value'])  for var, value in bindings.items() ] 
            if verbose:
                print( app)
            array.append(app)
        if verbose:
            print(len(array))
        return array

    except Exception as e :
        print("The operation failed", e)
    
# ASk queries
def run_ask_query(queryString):
    to_run = prefixString + "\n" + queryString

    sparql = SPARQLWrapper("http://a256-gc1-03.srv.aau.dk:5820/sparql")
    sparql.setTimeout(300)
    sparql.setReturnFormat(JSON)
    sparql.setQuery(to_run)

    try :
        return sparql.query().convert()

    except Exception as e :
        print("The operation failed", e)

# %% [markdown]
# # Sport Workflow Series (Tennis explorative search")
#
# Consider the following exploratory information need:
#
# > investigate tennis and find the main BGPs related to this sport. Compare players per countries, awards of the players and tournament.

# %% [markdown]
# ## Useful URIs for the current workflow
# The following are given:
#
# | IRI           | Description   | Role      |
# | -----------   | -----------   |-----------|
# | `wdt:P1647`   | subproperty   | predicate |
# | `wdt:P31`     | instance of   | predicate |
# | `wdt:P106`    | profession    | predicate |
# | `wdt:P279`    | subclass      | predicate |
# | `wdt:P27`     | nationality   | predicate |
# | `wd:Q5`| Human       | node |
# | `wd:Q1426`| Roger Federer       | node |
# | `wd:Q11459`| Serena Williams       | node |

# %% [markdown]
# Also consider
#
# ```
# wd:Q1426 ?p ?obj .
# ```
#
# is the BGP to retrieve all **properties of Roger Federer**
#
# Please consider that when you return a resource, you should return the IRI and the label of the resource. In particular, when the task require you to identify a BGP the result set must always be a list of couples IRI - label.
#
#
#
# The workload should:
#
#
# 1. Identify the BGP for tennis player
#
# 2. Identify the BGP for tennis tournament
#
# 3. Return the four Grand Slam of tennis (hint: One of these four is Wimbledon) (the result set must be a list of four couples Grand Slam IRI and label).
#
# 4. Find the three different type of possible surfaces in a tennis court (the result set must be a list of three couples surface IRI and label).
#
# 5. Return the tournaments played in the 2018 Wimbledon Championships edition with the related winners (hint: men and women do not play together, there are two distinct tournament ) (the result set must be a list of elements with tournament IRI and label, and winner IRI and label).
#
# 6. Consider the tennis players born after 1975, return who won more Grand Slams and cut the result to the top-10 (the result set must be a list of triples player IRI, label and #victories).
#
# 7. Consider the country for sport property of the tennis player (NO Country of citizenship). Return the countries with at least one player who won at least one edition of each Grand Slam (the result set must be a list of country IRI and label).
#
# 8. Consider the country for sport property of the tennis player (NO Country of citizenship). Return the countries with at least one player who was ranked 1 in the tennis ranking  (the result set must be a list of country IRI and label).

# %% [markdown]
# ## Task 1
# Identify the BGP for tennis player

# %%
# query example
queryString = """
SELECT DISTINCT ?p ?name
WHERE {
   # bind something
   wd:Q1426 ?p ?obj .
   # get the label
   # ?p sc:name ?name.
}
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P1006'), ('name', 'Nationale Thesaurus voor Auteurs ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P103'), ('name', 'native language')]
# [('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('p', 'http://www.wikidata.org/prop/direct/P108'), ('name', 'employer')]
# [('p', 'http://www.wikidata.org/prop/direct/P1263'), ('name', 'NNDB people ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1280'), ('name', 'CONOR.SI ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1284'), ('name', 'Munzinger person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1285'), ('name', 'Munzinger Sport number')]
# [('p', 'http://www.wikidata.org/prop/direct/P1296'), ('name', 'Gran Enciclopèdia Catalana ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1343'), ('name', 'described by source')]
# [('p', 'http://www.wikidata.org/prop/direct/P1344'), ('name', 'participant in')]
# [('p', 'http://www.wikidata.org/prop/direct/P1352'), ('name', 'ranking')]
# [('p', 'http://www.wikidata.org/prop/direct/P140'), ('name', 'religion')]
# [('p', 'http://www.wikidata.org/prop/direct/P1412'), ('name', 'languages spoken, written or signed')]
# [('p', 'http://www.wikidata.org/prop/direct/P1417'), ('name', 'Encyclopædia Britannica Online ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1447'), ('name', 'Sports-Reference.com Olympic athlete ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1532'), ('name', 'country for sport')]
# [('p', 'http://www.wikidata.org/prop/direct/P166'), ('name', 'award received')]
# [('p', 'http://www.wikidata.org/prop/direct/P1695'), ('name', 'NLP ID (unique)')]
# [('p', 'http://www.wikidata.org/prop/direct/P1741'), ('name', 'GTAA ID')]
# 20

# %% [markdown]
# #### Found wd:Q10833314 ('tennis player')

# %%
# TASK1: Identify the BGP for tennis player
# With this query I'm trying to find Roger Federer's (wd:Q1426) profession (wdt:P106)
queryString = """
SELECT DISTINCT ?profession ?name
WHERE {
   # bind something
   wd:Q1426 wdt:P106 ?profession .
   # get the label
   # ?profession sc:name ?name.
}
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('profession', 'http://www.wikidata.org/entity/Q10833314'), ('name', 'tennis player')]
# 1

# %%
# Initially, I made a wrong interpretation and thought that I had to find all the tennis players 
# so the following queries are just useless!

# %%
# Find all tennis player (wd:Q10833314) 
queryString = """
SELECT DISTINCT ?player ?name
WHERE {
   # bind something
   wd:Q10833314 wdt:P106 ?player .
   # get the label
   # ?player sc:name ?name.
}
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# Empty

# %%
# Find all tennis player (wd:Q10833314) 
queryString = """
SELECT DISTINCT ?player ?name
WHERE {
   # bind something
   wd:Q10833314 ^wdt:P106 ?player .
   # get the label
   # ?player sc:name ?name.
}
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('player', 'http://www.wikidata.org/entity/Q1683632'), ('name', 'Jaroslav Navrátil')]
# [('player', 'http://www.wikidata.org/entity/Q138094'), ('name', 'Anna Karolína Schmiedlová')]
# [('player', 'http://www.wikidata.org/entity/Q15197746'), ('name', 'Wesley Koolhof')]
# [('player', 'http://www.wikidata.org/entity/Q1558013'), ('name', 'Pierre Barthès')]
# [('player', 'http://www.wikidata.org/entity/Q15849678'), ('name', 'Sue Partridge')]
# [('player', 'http://www.wikidata.org/entity/Q15880574'), ('name', 'Paul Oosterbaan')]
# [('player', 'http://www.wikidata.org/entity/Q240837'), ('name', 'Rika Fujiwara')]
# [('player', 'http://www.wikidata.org/entity/Q4134097'), ('name', 'Margarita Gasparyan')]
# [('player', 'http://www.wikidata.org/entity/Q589611'), ('name', 'Philippe Chatrier')]
# [('player', 'http://www.wikidata.org/entity/Q16009513'), ('name', 'James Bayley')]
# [('player', 'http://www.wikidata.org/entity/Q16023406'), ('name', 'Samuel T. Chase')]
# [('player', 'http://www.wikidata.org/entity/Q16063202'), ('name', 'Agnete Goldschmidt')]
# [('player', 'http://www.wikidata.org/entity/Q16065254'), ('name', 'Thorkil Hillerup')]
# [('player', 'http://www.wikidata.org/entity/Q16067006'), ('name', 'Lois Moyes Bickle')]
# [('player', 'http://www.wikidata.org/entity/Q1660141'), ('name', 'Perry Jones')]
# [('player', 'http://www.wikidata.org/entity/Q299959'), ('name', 'Eileen Bennett Whittingstall')]
# [('player', 'http://www.wikidata.org/entity/Q16203224'), ('name', 'Frederick Campbell Colston')]
# [('player', 'http://www.wikidata.org/entity/Q16204467'), ('name', 'Andrew Drew')]
# [('player', 'http://www.wikidata.org/entity/Q16208155'), ('name', 'Chris Forney')]
# [('player', 'http://www.wikidata.org/entity/Q16210951'), ('name', 'N. M. Smith')]
# 20

# %%
# Find all tennis player (wd:Q10833314), extending limit to 100
queryString = """
SELECT DISTINCT ?player ?name
WHERE {
   # bind something
   wd:Q10833314 ^wdt:P106 ?player .
   # get the label
   # ?player sc:name ?name.
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('player', 'http://www.wikidata.org/entity/Q1683632'), ('name', 'Jaroslav Navrátil')]
# [('player', 'http://www.wikidata.org/entity/Q138094'), ('name', 'Anna Karolína Schmiedlová')]
# [('player', 'http://www.wikidata.org/entity/Q15197746'), ('name', 'Wesley Koolhof')]
# [('player', 'http://www.wikidata.org/entity/Q1558013'), ('name', 'Pierre Barthès')]
# [('player', 'http://www.wikidata.org/entity/Q15849678'), ('name', 'Sue Partridge')]
# [('player', 'http://www.wikidata.org/entity/Q15880574'), ('name', 'Paul Oosterbaan')]
# [('player', 'http://www.wikidata.org/entity/Q240837'), ('name', 'Rika Fujiwara')]
# [('player', 'http://www.wikidata.org/entity/Q4134097'), ('name', 'Margarita Gasparyan')]
# [('player', 'http://www.wikidata.org/entity/Q589611'), ('name', 'Philippe Chatrier')]
# [('player', 'http://www.wikidata.org/entity/Q16009513'), ('name', 'James Bayley')]
# [('player', 'http://www.wikidata.org/entity/Q16023406'), ('name', 'Samuel T. Chase')]
# [('player', 'http://www.wikidata.org/entity/Q16063202'), ('name', 'Agnete Goldschmidt')]
# [('player', 'http://www.wikidata.org/entity/Q16065254'), ('name', 'Thorkil Hillerup')]
# [('player', 'http://www.wikidata.org/entity/Q16067006'), ('name', 'Lois Moyes Bickle')]
# [('player', 'http://www.wikidata.org/entity/Q1660141'), ('name', 'Perry Jones')]
# [('player', 'http://www.wikidata.org/entity/Q299959'), ('name', 'Eileen Bennett Whittingstall')]
# [('player', 'http://www.wikidata.org/entity/Q16203224'), ('name', 'Frederick Campbell Colston')]
# [('player', 'http://www.wikidata.org/entity/Q16204467'), ('name', 'Andrew Drew')]
# [('player', 'http://www.wikidata.org/entity/Q16208155'), ('name', 'Chris Forney')]
# [('player', 'http://www.wikidata.org/entity/Q16210951'), ('name', 'N. M. Smith')]
# [('player', 'http://www.wikidata.org/entity/Q16219279'), ('name', 'William S. Bond')]
# [('player', 'http://www.wikidata.org/entity/Q16219370'), ('name', 'John Strachan')]
# [('player', 'http://www.wikidata.org/entity/Q16224596'), ('name', 'David Kabiller')]
# [('player', 'http://www.wikidata.org/entity/Q16224618'), ('name', 'Janet Lagasse')]
# [('player', 'http://www.wikidata.org/entity/Q16224631'), ('name', 'Lee So-ra')]
# [('player', 'http://www.wikidata.org/entity/Q459223'), ('name', 'Paul Lebreton')]
# [('player', 'http://www.wikidata.org/entity/Q7281705'), ('name', 'Radu Albot')]
# [('player', 'http://www.wikidata.org/entity/Q17189986'), ('name', 'Will Coghlan')]
# [('player', 'http://www.wikidata.org/entity/Q18918709'), ('name', 'Markéta Vondroušová')]
# [('player', 'http://www.wikidata.org/entity/Q6408932'), ('name', 'Kim Jones')]
# [('player', 'http://www.wikidata.org/entity/Q7176198'), ('name', 'Peter Oatey')]
# [('player', 'http://www.wikidata.org/entity/Q17291218'), ('name', 'Djordje Djokovic')]
# [('player', 'http://www.wikidata.org/entity/Q17302035'), ('name', 'Mary Hamm')]
# [('player', 'http://www.wikidata.org/entity/Q17303008'), ('name', 'Petra Hradecká')]
# [('player', 'http://www.wikidata.org/entity/Q17323657'), ('name', 'Sviatlana Pirazhenka')]
# [('player', 'http://www.wikidata.org/entity/Q17327545'), ('name', 'Marcelo Zormann')]
# [('player', 'http://www.wikidata.org/entity/Q17525743'), ('name', 'Sanaz Marand')]
# [('player', 'http://www.wikidata.org/entity/Q193661'), ('name', 'Stan Wawrinka')]
# [('player', 'http://www.wikidata.org/entity/Q3597288'), ('name', 'Marko Djokovic')]
# [('player', 'http://www.wikidata.org/entity/Q76338'), ('name', 'Sabine Lisicki')]
# [('player', 'http://www.wikidata.org/entity/Q966542'), ('name', 'Roberto Bautista Agut')]
# [('player', 'http://www.wikidata.org/entity/Q12768184'), ('name', 'Jozef Kovalík')]
# [('player', 'http://www.wikidata.org/entity/Q17442289'), ('name', 'David Sherbeck')]
# [('player', 'http://www.wikidata.org/entity/Q237146'), ('name', 'Lara Arruabarrena')]
# [('player', 'http://www.wikidata.org/entity/Q15693148'), ('name', 'Lo Man Wai')]
# [('player', 'http://www.wikidata.org/entity/Q17612829'), ('name', 'Hunter Reese')]
# [('player', 'http://www.wikidata.org/entity/Q17626628'), ('name', 'Ernesto Escobedo')]
# [('player', 'http://www.wikidata.org/entity/Q53410'), ('name', 'John Doeg')]
# [('player', 'http://www.wikidata.org/entity/Q54546'), ('name', 'Nancy Richey')]
# [('player', 'http://www.wikidata.org/entity/Q4169985'), ('name', 'Bermet Duvanaeva')]
# [('player', 'http://www.wikidata.org/entity/Q18085277'), ('name', 'Armistead Neely')]
# [('player', 'http://www.wikidata.org/entity/Q18091446'), ('name', 'Hank Irvine')]
# [('player', 'http://www.wikidata.org/entity/Q18113506'), ('name', 'Robin Blakelock')]
# [('player', 'http://www.wikidata.org/entity/Q18129396'), ('name', 'Gao Xin')]
# [('player', 'http://www.wikidata.org/entity/Q19406'), ('name', 'David Goffin')]
# [('player', 'http://www.wikidata.org/entity/Q26799554'), ('name', 'Jeffrey John Wolf')]
# [('player', 'http://www.wikidata.org/entity/Q355333'), ('name', 'Marcin Matkowski')]
# [('player', 'http://www.wikidata.org/entity/Q4800760'), ('name', 'Wang Qiang')]
# [('player', 'http://www.wikidata.org/entity/Q1260231'), ('name', 'Geoff Masters')]
# [('player', 'http://www.wikidata.org/entity/Q17364412'), ('name', 'Maximilian Marterer')]
# [('player', 'http://www.wikidata.org/entity/Q19330576'), ('name', 'Darren Walsh')]
# [('player', 'http://www.wikidata.org/entity/Q5880437'), ('name', 'Gisela Riera')]
# [('player', 'http://www.wikidata.org/entity/Q6376017'), ('name', 'Kateřina Böhmová')]
# [('player', 'http://www.wikidata.org/entity/Q72091'), ('name', 'Martin Sinner')]
# [('player', 'http://www.wikidata.org/entity/Q14905846'), ('name', 'Borna Ćorić')]
# [('player', 'http://www.wikidata.org/entity/Q207352'), ('name', 'Agnieszka Radwańska')]
# [('player', 'http://www.wikidata.org/entity/Q20968624'), ('name', 'Viktória Kužmová')]
# [('player', 'http://www.wikidata.org/entity/Q20982979'), ('name', 'Miyu Kato')]
# [('player', 'http://www.wikidata.org/entity/Q20983768'), ('name', 'Kerstin Peckl')]
# [('player', 'http://www.wikidata.org/entity/Q21001023'), ('name', 'Facundo Mena')]
# [('player', 'http://www.wikidata.org/entity/Q21622155'), ('name', 'Richard Muzaev')]
# [('player', 'http://www.wikidata.org/entity/Q21622265'), ('name', 'Akiko Ōmae')]
# [('player', 'http://www.wikidata.org/entity/Q21970595'), ('name', 'Eléonora Molinaro')]
# [('player', 'http://www.wikidata.org/entity/Q312343'), ('name', 'Milos Raonic')]
# [('player', 'http://www.wikidata.org/entity/Q22022537'), ('name', 'Martin Zander')]
# [('player', 'http://www.wikidata.org/entity/Q22086227'), ('name', 'Ellen Perez')]
# [('player', 'http://www.wikidata.org/entity/Q22087891'), ('name', 'Alexandra Chong')]
# [('player', 'http://www.wikidata.org/entity/Q22958938'), ('name', 'Alex de Minaur')]
# [('player', 'http://www.wikidata.org/entity/Q22959065'), ('name', 'Blake Ellis')]
# [('player', 'http://www.wikidata.org/entity/Q21032187'), ('name', 'Melanie Molitorová')]
# [('player', 'http://www.wikidata.org/entity/Q22911321'), ('name', 'Eugeniusz Czerepaniak')]
# [('player', 'http://www.wikidata.org/entity/Q22953456'), ('name', 'Agnese Gustmane')]
# [('player', 'http://www.wikidata.org/entity/Q22957659'), ('name', 'Jane Régny')]
# [('player', 'http://www.wikidata.org/entity/Q22959202'), ('name', 'Alvin Gardiner')]
# [('player', 'http://www.wikidata.org/entity/Q22961763'), ('name', 'Nurin Nabilah Roslan')]
# [('player', 'http://www.wikidata.org/entity/Q22964651'), ('name', 'Antoni Juanico i Torres')]
# [('player', 'http://www.wikidata.org/entity/Q22965148'), ('name', 'Francesc Sindreu i Pons')]
# [('player', 'http://www.wikidata.org/entity/Q3051240'), ('name', 'Elizabeth Little')]
# [('player', 'http://www.wikidata.org/entity/Q2139295'), ('name', 'Alain Gerbault')]
# [('player', 'http://www.wikidata.org/entity/Q24203552'), ('name', 'Alexander Kaye Butterworth')]
# [('player', 'http://www.wikidata.org/entity/Q26207574'), ('name', 'Doaa el-Ghobashy')]
# [('player', 'http://www.wikidata.org/entity/Q26209630'), ('name', 'Zhu Aiwen')]
# [('player', 'http://www.wikidata.org/entity/Q26210785'), ('name', 'Kaden Hensel')]
# [('player', 'http://www.wikidata.org/entity/Q26269760'), ('name', 'Giorgia Marchetti')]
# [('player', 'http://www.wikidata.org/entity/Q27032196'), ('name', 'Polina Merenkova')]
# [('player', 'http://www.wikidata.org/entity/Q27049237'), ('name', 'Ljubomir Čelebić')]
# [('player', 'http://www.wikidata.org/entity/Q27057687'), ('name', 'Gülberk Gültekin')]
# [('player', 'http://www.wikidata.org/entity/Q27244469'), ('name', 'Agustina Lepore')]
# [('player', 'http://www.wikidata.org/entity/Q27495841'), ('name', 'Yamile Fors Guerra')]
# [('player', 'http://www.wikidata.org/entity/Q7454263'), ('name', 'Sergio Galdós')]
# 100

# %%
# Find all tennis player (wd:Q10833314), extending limit to 500
queryString = """
SELECT DISTINCT ?player ?name
WHERE {
   # bind something
   wd:Q10833314 ^wdt:P106 ?player .
   # get the label
   # ?player sc:name ?name.
}
LIMIT 500
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('player', 'http://www.wikidata.org/entity/Q1683632'), ('name', 'Jaroslav Navrátil')]
# [('player', 'http://www.wikidata.org/entity/Q138094'), ('name', 'Anna Karolína Schmiedlová')]
# [('player', 'http://www.wikidata.org/entity/Q15197746'), ('name', 'Wesley Koolhof')]
# [('player', 'http://www.wikidata.org/entity/Q1558013'), ('name', 'Pierre Barthès')]
# [('player', 'http://www.wikidata.org/entity/Q15849678'), ('name', 'Sue Partridge')]
# [('player', 'http://www.wikidata.org/entity/Q15880574'), ('name', 'Paul Oosterbaan')]
# [('player', 'http://www.wikidata.org/entity/Q240837'), ('name', 'Rika Fujiwara')]
# [('player', 'http://www.wikidata.org/entity/Q4134097'), ('name', 'Margarita Gasparyan')]
# [('player', 'http://www.wikidata.org/entity/Q589611'), ('name', 'Philippe Chatrier')]
# [('player', 'http://www.wikidata.org/entity/Q16009513'), ('name', 'James Bayley')]
# [('player', 'http://www.wikidata.org/entity/Q16023406'), ('name', 'Samuel T. Chase')]
# [('player', 'http://www.wikidata.org/entity/Q16063202'), ('name', 'Agnete Goldschmidt')]
# [('player', 'http://www.wikidata.org/entity/Q16065254'), ('name', 'Thorkil Hillerup')]
# [('player', 'http://www.wikidata.org/entity/Q16067006'), ('name', 'Lois Moyes Bickle')]
# [('player', 'http://www.wikidata.org/entity/Q1660141'), ('name', 'Perry Jones')]
# [('player', 'http://www.wikidata.org/entity/Q299959'), ('name', 'Eileen Bennett Whittingstall')]
# [('player', 'http://www.wikidata.org/entity/Q16203224'), ('name', 'Frederick Campbell Colston')]
# [('player', 'http://www.wikidata.org/entity/Q16204467'), ('name', 'Andrew Drew')]
# [('player', 'http://www.wikidata.org/entity/Q16208155'), ('name', 'Chris Forney')]
# [('player', 'http://www.wikidata.org/entity/Q16210951'), ('name', 'N. M. Smith')]
# [('player', 'http://www.wikidata.org/entity/Q16219279'), ('name', 'William S. Bond')]
# [('player', 'http://www.wikidata.org/entity/Q16219370'), ('name', 'John Strachan')]
# [('player', 'http://www.wikidata.org/entity/Q16224596'), ('name', 'David Kabiller')]
# [('player', 'http://www.wikidata.org/entity/Q16224618'), ('name', 'Janet Lagasse')]
# [('player', 'http://www.wikidata.org/entity/Q16224631'), ('name', 'Lee So-ra')]
# [('player', 'http://www.wikidata.org/entity/Q459223'), ('name', 'Paul Lebreton')]
# [('player', 'http://www.wikidata.org/entity/Q7281705'), ('name', 'Radu Albot')]
# [('player', 'http://www.wikidata.org/entity/Q17189986'), ('name', 'Will Coghlan')]
# [('player', 'http://www.wikidata.org/entity/Q18918709'), ('name', 'Markéta Vondroušová')]
# [('player', 'http://www.wikidata.org/entity/Q6408932'), ('name', 'Kim Jones')]
# [('player', 'http://www.wikidata.org/entity/Q7176198'), ('name', 'Peter Oatey')]
# [('player', 'http://www.wikidata.org/entity/Q17291218'), ('name', 'Djordje Djokovic')]
# [('player', 'http://www.wikidata.org/entity/Q17302035'), ('name', 'Mary Hamm')]
# [('player', 'http://www.wikidata.org/entity/Q17303008'), ('name', 'Petra Hradecká')]
# [('player', 'http://www.wikidata.org/entity/Q17323657'), ('name', 'Sviatlana Pirazhenka')]
# [('player', 'http://www.wikidata.org/entity/Q17327545'), ('name', 'Marcelo Zormann')]
# [('player', 'http://www.wikidata.org/entity/Q17525743'), ('name', 'Sanaz Marand')]
# [('player', 'http://www.wikidata.org/entity/Q193661'), ('name', 'Stan Wawrinka')]
# [('player', 'http://www.wikidata.org/entity/Q3597288'), ('name', 'Marko Djokovic')]
# [('player', 'http://www.wikidata.org/entity/Q76338'), ('name', 'Sabine Lisicki')]
# [('player', 'http://www.wikidata.org/entity/Q966542'), ('name', 'Roberto Bautista Agut')]
# [('player', 'http://www.wikidata.org/entity/Q12768184'), ('name', 'Jozef Kovalík')]
# [('player', 'http://www.wikidata.org/entity/Q17442289'), ('name', 'David Sherbeck')]
# [('player', 'http://www.wikidata.org/entity/Q237146'), ('name', 'Lara Arruabarrena')]
# [('player', 'http://www.wikidata.org/entity/Q15693148'), ('name', 'Lo Man Wai')]
# [('player', 'http://www.wikidata.org/entity/Q17612829'), ('name', 'Hunter Reese')]
# [('player', 'http://www.wikidata.org/entity/Q17626628'), ('name', 'Ernesto Escobedo')]
# [('player', 'http://www.wikidata.org/entity/Q53410'), ('name', 'John Doeg')]
# [('player', 'http://www.wikidata.org/entity/Q54546'), ('name', 'Nancy Richey')]
# [('player', 'http://www.wikidata.org/entity/Q4169985'), ('name', 'Bermet Duvanaeva')]
# [('player', 'http://www.wikidata.org/entity/Q18085277'), ('name', 'Armistead Neely')]
# [('player', 'http://www.wikidata.org/entity/Q18091446'), ('name', 'Hank Irvine')]
# [('player', 'http://www.wikidata.org/entity/Q18113506'), ('name', 'Robin Blakelock')]
# [('player', 'http://www.wikidata.org/entity/Q18129396'), ('name', 'Gao Xin')]
# [('player', 'http://www.wikidata.org/entity/Q19406'), ('name', 'David Goffin')]
# [('player', 'http://www.wikidata.org/entity/Q26799554'), ('name', 'Jeffrey John Wolf')]
# [('player', 'http://www.wikidata.org/entity/Q355333'), ('name', 'Marcin Matkowski')]
# [('player', 'http://www.wikidata.org/entity/Q4800760'), ('name', 'Wang Qiang')]
# [('player', 'http://www.wikidata.org/entity/Q1260231'), ('name', 'Geoff Masters')]
# [('player', 'http://www.wikidata.org/entity/Q17364412'), ('name', 'Maximilian Marterer')]
# [('player', 'http://www.wikidata.org/entity/Q19330576'), ('name', 'Darren Walsh')]
# [('player', 'http://www.wikidata.org/entity/Q5880437'), ('name', 'Gisela Riera')]
# [('player', 'http://www.wikidata.org/entity/Q6376017'), ('name', 'Kateřina Böhmová')]
# [('player', 'http://www.wikidata.org/entity/Q72091'), ('name', 'Martin Sinner')]
# [('player', 'http://www.wikidata.org/entity/Q14905846'), ('name', 'Borna Ćorić')]
# [('player', 'http://www.wikidata.org/entity/Q207352'), ('name', 'Agnieszka Radwańska')]
# [('player', 'http://www.wikidata.org/entity/Q20968624'), ('name', 'Viktória Kužmová')]
# [('player', 'http://www.wikidata.org/entity/Q20982979'), ('name', 'Miyu Kato')]
# [('player', 'http://www.wikidata.org/entity/Q20983768'), ('name', 'Kerstin Peckl')]
# [('player', 'http://www.wikidata.org/entity/Q21001023'), ('name', 'Facundo Mena')]
# [('player', 'http://www.wikidata.org/entity/Q21622155'), ('name', 'Richard Muzaev')]
# [('player', 'http://www.wikidata.org/entity/Q21622265'), ('name', 'Akiko Ōmae')]
# [('player', 'http://www.wikidata.org/entity/Q21970595'), ('name', 'Eléonora Molinaro')]
# [('player', 'http://www.wikidata.org/entity/Q312343'), ('name', 'Milos Raonic')]
# [('player', 'http://www.wikidata.org/entity/Q22022537'), ('name', 'Martin Zander')]
# [('player', 'http://www.wikidata.org/entity/Q22086227'), ('name', 'Ellen Perez')]
# [('player', 'http://www.wikidata.org/entity/Q22087891'), ('name', 'Alexandra Chong')]
# [('player', 'http://www.wikidata.org/entity/Q22958938'), ('name', 'Alex de Minaur')]
# [('player', 'http://www.wikidata.org/entity/Q22959065'), ('name', 'Blake Ellis')]
# [('player', 'http://www.wikidata.org/entity/Q21032187'), ('name', 'Melanie Molitorová')]
# [('player', 'http://www.wikidata.org/entity/Q22911321'), ('name', 'Eugeniusz Czerepaniak')]
# [('player', 'http://www.wikidata.org/entity/Q22953456'), ('name', 'Agnese Gustmane')]
# [('player', 'http://www.wikidata.org/entity/Q22957659'), ('name', 'Jane Régny')]
# [('player', 'http://www.wikidata.org/entity/Q22959202'), ('name', 'Alvin Gardiner')]
# [('player', 'http://www.wikidata.org/entity/Q22961763'), ('name', 'Nurin Nabilah Roslan')]
# [('player', 'http://www.wikidata.org/entity/Q22964651'), ('name', 'Antoni Juanico i Torres')]
# [('player', 'http://www.wikidata.org/entity/Q22965148'), ('name', 'Francesc Sindreu i Pons')]
# [('player', 'http://www.wikidata.org/entity/Q3051240'), ('name', 'Elizabeth Little')]
# [('player', 'http://www.wikidata.org/entity/Q2139295'), ('name', 'Alain Gerbault')]
# [('player', 'http://www.wikidata.org/entity/Q24203552'), ('name', 'Alexander Kaye Butterworth')]
# [('player', 'http://www.wikidata.org/entity/Q26207574'), ('name', 'Doaa el-Ghobashy')]
# [('player', 'http://www.wikidata.org/entity/Q26209630'), ('name', 'Zhu Aiwen')]
# [('player', 'http://www.wikidata.org/entity/Q26210785'), ('name', 'Kaden Hensel')]
# [('player', 'http://www.wikidata.org/entity/Q26269760'), ('name', 'Giorgia Marchetti')]
# [('player', 'http://www.wikidata.org/entity/Q27032196'), ('name', 'Polina Merenkova')]
# [('player', 'http://www.wikidata.org/entity/Q27049237'), ('name', 'Ljubomir Čelebić')]
# [('player', 'http://www.wikidata.org/entity/Q27057687'), ('name', 'Gülberk Gültekin')]
# [('player', 'http://www.wikidata.org/entity/Q27244469'), ('name', 'Agustina Lepore')]
# [('player', 'http://www.wikidata.org/entity/Q27495841'), ('name', 'Yamile Fors Guerra')]
# [('player', 'http://www.wikidata.org/entity/Q7454263'), ('name', 'Sergio Galdós')]
# [('player', 'http://www.wikidata.org/entity/Q30350285'), ('name', 'Jonathan Stokke')]
# [('player', 'http://www.wikidata.org/entity/Q17747390'), ('name', 'Quirine Lemoine')]
# [('player', 'http://www.wikidata.org/entity/Q239758'), ('name', 'Arantxa Rus')]
# [('player', 'http://www.wikidata.org/entity/Q36489953'), ('name', 'Daphne van de Zande')]
# [('player', 'http://www.wikidata.org/entity/Q1296314'), ('name', 'Effrosini Paspati')]
# [('player', 'http://www.wikidata.org/entity/Q22958616'), ('name', 'Kate Brasher')]
# [('player', 'http://www.wikidata.org/entity/Q30778'), ('name', 'Ashley Harkleroad')]
# [('player', 'http://www.wikidata.org/entity/Q435255'), ('name', 'Shirley Brasher')]
# [('player', 'http://www.wikidata.org/entity/Q437281'), ('name', 'Lee Hyung-taik')]
# [('player', 'http://www.wikidata.org/entity/Q437350'), ('name', 'Doris Metaxa')]
# [('player', 'http://www.wikidata.org/entity/Q439861'), ('name', 'Konstantinos Paspatis')]
# [('player', 'http://www.wikidata.org/entity/Q439942'), ('name', 'Marcelo Melo')]
# [('player', 'http://www.wikidata.org/entity/Q440093'), ('name', 'Heidi El Tabakh')]
# [('player', 'http://www.wikidata.org/entity/Q440157'), ('name', 'Miyoko Asahina')]
# [('player', 'http://www.wikidata.org/entity/Q440162'), ('name', 'Valeria Savinykh')]
# [('player', 'http://www.wikidata.org/entity/Q440443'), ('name', 'Sandra Cecchini')]
# [('player', 'http://www.wikidata.org/entity/Q440482'), ('name', 'Alex Bogomolov')]
# [('player', 'http://www.wikidata.org/entity/Q442087'), ('name', 'Jelena Pandžić')]
# [('player', 'http://www.wikidata.org/entity/Q445602'), ('name', 'Manuel Santana')]
# [('player', 'http://www.wikidata.org/entity/Q450264'), ('name', 'Alycia Moulton')]
# [('player', 'http://www.wikidata.org/entity/Q452365'), ('name', 'Nikola Pilić')]
# [('player', 'http://www.wikidata.org/entity/Q453385'), ('name', 'Yuka Yoshida')]
# [('player', 'http://www.wikidata.org/entity/Q454170'), ('name', 'Kerry Harris')]
# [('player', 'http://www.wikidata.org/entity/Q454194'), ('name', 'P. Girod')]
# [('player', 'http://www.wikidata.org/entity/Q454255'), ('name', 'Dorothy Shepherd-Barron')]
# [('player', 'http://www.wikidata.org/entity/Q454563'), ('name', 'Sofie Castenschiold')]
# [('player', 'http://www.wikidata.org/entity/Q455136'), ('name', 'Anders Järryd')]
# [('player', 'http://www.wikidata.org/entity/Q455165'), ('name', 'Florencia Labat')]
# [('player', 'http://www.wikidata.org/entity/Q455411'), ('name', 'Tom Okker')]
# [('player', 'http://www.wikidata.org/entity/Q455453'), ('name', 'Rika Hiraki')]
# [('player', 'http://www.wikidata.org/entity/Q455507'), ('name', 'Ana Jovanović')]
# [('player', 'http://www.wikidata.org/entity/Q455711'), ('name', 'Rachel McQuillan')]
# [('player', 'http://www.wikidata.org/entity/Q456145'), ('name', 'Friedrich Wilhelm Rahe')]
# [('player', 'http://www.wikidata.org/entity/Q457051'), ('name', 'Daniel Gimeno-Traver')]
# [('player', 'http://www.wikidata.org/entity/Q457484'), ('name', 'Raemon Sluiter')]
# [('player', 'http://www.wikidata.org/entity/Q458285'), ('name', 'Marion Jessup')]
# [('player', 'http://www.wikidata.org/entity/Q458484'), ('name', 'Mary Ewing Outerbridge')]
# [('player', 'http://www.wikidata.org/entity/Q458617'), ('name', 'Renée Schuurman')]
# [('player', 'http://www.wikidata.org/entity/Q909744'), ('name', 'Brent Haygarth')]
# [('player', 'http://www.wikidata.org/entity/Q105868'), ('name', 'Gabriela Sabatini')]
# [('player', 'http://www.wikidata.org/entity/Q506606'), ('name', 'Mark Edmondson')]
# [('player', 'http://www.wikidata.org/entity/Q2393817'), ('name', 'Tara Deodhar')]
# [('player', 'http://www.wikidata.org/entity/Q2791107'), ('name', 'Jean Washer')]
# [('player', 'http://www.wikidata.org/entity/Q295488'), ('name', 'Michaël Llodra')]
# [('player', 'http://www.wikidata.org/entity/Q310419'), ('name', 'Nenad Zimonjić')]
# [('player', 'http://www.wikidata.org/entity/Q53393'), ('name', 'Jimmy Connors')]
# [('player', 'http://www.wikidata.org/entity/Q538191'), ('name', 'John Hartley')]
# [('player', 'http://www.wikidata.org/entity/Q545299'), ('name', 'Dája Bedáňová')]
# [('player', 'http://www.wikidata.org/entity/Q546287'), ('name', 'Dick Davies')]
# [('player', 'http://www.wikidata.org/entity/Q546733'), ('name', 'Thierry Ascione')]
# [('player', 'http://www.wikidata.org/entity/Q552349'), ('name', 'Jean-Julien Rojer')]
# [('player', 'http://www.wikidata.org/entity/Q552502'), ('name', 'Fernando Luna')]
# [('player', 'http://www.wikidata.org/entity/Q552646'), ('name', 'Philippe Washer')]
# [('player', 'http://www.wikidata.org/entity/Q552792'), ('name', 'Paul Chamberlin')]
# [('player', 'http://www.wikidata.org/entity/Q553368'), ('name', 'Karim Alami')]
# [('player', 'http://www.wikidata.org/entity/Q942494'), ('name', 'Jan Hájek')]
# [('player', 'http://www.wikidata.org/entity/Q202342'), ('name', 'Margaret Court')]
# [('player', 'http://www.wikidata.org/entity/Q230253'), ('name', 'María José Martínez Sánchez')]
# [('player', 'http://www.wikidata.org/entity/Q233234'), ('name', 'Virginia Wade')]
# [('player', 'http://www.wikidata.org/entity/Q258901'), ('name', 'Henrieta Nagyová')]
# [('player', 'http://www.wikidata.org/entity/Q373612'), ('name', 'Blaž Kavčič')]
# [('player', 'http://www.wikidata.org/entity/Q586192'), ('name', 'Niels Desein')]
# [('player', 'http://www.wikidata.org/entity/Q595234'), ('name', 'Jack Cummings')]
# [('player', 'http://www.wikidata.org/entity/Q599540'), ('name', 'Blaine Willenborg')]
# [('player', 'http://www.wikidata.org/entity/Q605230'), ('name', 'José López-Maeso')]
# [('player', 'http://www.wikidata.org/entity/Q608012'), ('name', 'Antony Dupuis')]
# [('player', 'http://www.wikidata.org/entity/Q10118'), ('name', 'Victoria Azarenka')]
# [('player', 'http://www.wikidata.org/entity/Q1616815'), ('name', 'Nastassja Burnett')]
# [('player', 'http://www.wikidata.org/entity/Q162639'), ('name', 'Lew Hoad')]
# [('player', 'http://www.wikidata.org/entity/Q53550'), ('name', 'Althea Gibson')]
# [('player', 'http://www.wikidata.org/entity/Q658206'), ('name', 'Maria Teresa Riedl')]
# [('player', 'http://www.wikidata.org/entity/Q662627'), ('name', 'Michael Lammer')]
# [('player', 'http://www.wikidata.org/entity/Q662809'), ('name', 'Roderich Menzel')]
# [('player', 'http://www.wikidata.org/entity/Q668431'), ('name', 'Joost Winnink')]
# [('player', 'http://www.wikidata.org/entity/Q669082'), ('name', 'Sonya Jeyaseelan')]
# [('player', 'http://www.wikidata.org/entity/Q702989'), ('name', 'Yang Tsung-hua')]
# [('player', 'http://www.wikidata.org/entity/Q1342349'), ('name', 'Vivian McGrath')]
# [('player', 'http://www.wikidata.org/entity/Q13538'), ('name', 'Henri Kontinen')]
# [('player', 'http://www.wikidata.org/entity/Q1743002'), ('name', 'Robert Seguso')]
# [('player', 'http://www.wikidata.org/entity/Q1747609'), ('name', 'Margaret Stocks')]
# [('player', 'http://www.wikidata.org/entity/Q189542'), ('name', 'Stefan Edberg')]
# [('player', 'http://www.wikidata.org/entity/Q211636'), ('name', 'Serhiy Stakhovsky')]
# [('player', 'http://www.wikidata.org/entity/Q2533224'), ('name', 'Carling Bassett-Seguso')]
# [('player', 'http://www.wikidata.org/entity/Q253520'), ('name', 'Kathleen McKane Godfree')]
# [('player', 'http://www.wikidata.org/entity/Q2626148'), ('name', 'Elena Bogdan')]
# [('player', 'http://www.wikidata.org/entity/Q2834043'), ('name', 'Alexandre Sidorenko')]
# [('player', 'http://www.wikidata.org/entity/Q312639'), ('name', 'Fred Perry')]
# [('player', 'http://www.wikidata.org/entity/Q441027'), ('name', 'Oliver Marach')]
# [('player', 'http://www.wikidata.org/entity/Q502037'), ('name', 'Andrei Cherkasov')]
# [('player', 'http://www.wikidata.org/entity/Q53343'), ('name', 'Don Budge')]
# [('player', 'http://www.wikidata.org/entity/Q53424'), ('name', 'Shirley Fry')]
# [('player', 'http://www.wikidata.org/entity/Q54686'), ('name', 'Tony Trabert')]
# [('player', 'http://www.wikidata.org/entity/Q552678'), ('name', 'Santiago González')]
# [('player', 'http://www.wikidata.org/entity/Q577531'), ('name', 'Bill Bowrey')]
# [('player', 'http://www.wikidata.org/entity/Q61136'), ('name', 'Gottfried von Cramm')]
# [('player', 'http://www.wikidata.org/entity/Q928386'), ('name', 'John Bromwich')]
# [('player', 'http://www.wikidata.org/entity/Q525519'), ('name', 'Edith Rotch')]
# [('player', 'http://www.wikidata.org/entity/Q2273996'), ('name', 'Giorgio de Stefani')]
# [('player', 'http://www.wikidata.org/entity/Q2286163'), ('name', 'Silke Frankl')]
# [('player', 'http://www.wikidata.org/entity/Q259356'), ('name', 'Ann Haydon-Jones')]
# [('player', 'http://www.wikidata.org/entity/Q335209'), ('name', 'Greg Rusedski')]
# [('player', 'http://www.wikidata.org/entity/Q2542016'), ('name', 'Xavier Daufresne')]
# [('player', 'http://www.wikidata.org/entity/Q2546592'), ('name', 'Walter Trusendi')]
# [('player', 'http://www.wikidata.org/entity/Q2775207'), ('name', "Madeline O'Neill")]
# [('player', 'http://www.wikidata.org/entity/Q229315'), ('name', 'Eleni Daniilidou')]
# [('player', 'http://www.wikidata.org/entity/Q27862706'), ('name', 'Carol-Ann Kalogeropoulos')]
# [('player', 'http://www.wikidata.org/entity/Q27995847'), ('name', 'Anatolios Kalogeropoulos')]
# [('player', 'http://www.wikidata.org/entity/Q3339850'), ('name', 'Nikos Kalogeropoulos')]
# [('player', 'http://www.wikidata.org/entity/Q3343769'), ('name', 'Norman Farquharson')]
# [('player', 'http://www.wikidata.org/entity/Q3345990'), ('name', 'Monique Adamczak')]
# [('player', 'http://www.wikidata.org/entity/Q3356446'), ('name', 'Orlando H. Garrido')]
# [('player', 'http://www.wikidata.org/entity/Q3359933'), ('name', 'P Morley Lewis')]
# [('player', 'http://www.wikidata.org/entity/Q3361749'), ('name', 'Pam Casale')]
# [('player', 'http://www.wikidata.org/entity/Q3368543'), ('name', 'Pat Jones')]
# [('player', 'http://www.wikidata.org/entity/Q3368873'), ('name', 'Patrice Beust')]
# [('player', 'http://www.wikidata.org/entity/Q3369087'), ('name', 'Patricia Coleman')]
# [('player', 'http://www.wikidata.org/entity/Q3371590'), ('name', 'Paul Kronk')]
# [('player', 'http://www.wikidata.org/entity/Q3374791'), ('name', 'Penny Johnson')]
# [('player', 'http://www.wikidata.org/entity/Q53554'), ('name', 'Ricardo Alonso González')]
# [('player', 'http://www.wikidata.org/entity/Q1094731'), ('name', 'Clair Bee')]
# [('player', 'http://www.wikidata.org/entity/Q5081403'), ('name', 'Charles Owens')]
# [('player', 'http://www.wikidata.org/entity/Q5088263'), ('name', 'Chauncey Steele, Jr.')]
# [('player', 'http://www.wikidata.org/entity/Q5110871'), ('name', 'Christina Shakovets')]
# [('player', 'http://www.wikidata.org/entity/Q642602'), ('name', 'Alexandre-Athenase Noghès')]
# [('player', 'http://www.wikidata.org/entity/Q10853683'), ('name', 'Joana Valle Costa')]
# [('player', 'http://www.wikidata.org/entity/Q13015819'), ('name', 'Thassha Vitayaviroj')]
# [('player', 'http://www.wikidata.org/entity/Q13025480'), ('name', 'Benjamas Sangaram')]
# [('player', 'http://www.wikidata.org/entity/Q5126424'), ('name', 'Clarence Bruce, 3rd Baron Aberdare')]
# [('player', 'http://www.wikidata.org/entity/Q229002'), ('name', 'Alizé Cornet')]
# [('player', 'http://www.wikidata.org/entity/Q13474294'), ('name', 'Micheala Washington')]
# [('player', 'http://www.wikidata.org/entity/Q232432'), ('name', 'Raluca Olaru')]
# [('player', 'http://www.wikidata.org/entity/Q232566'), ('name', 'Hsieh Su-wei')]
# [('player', 'http://www.wikidata.org/entity/Q259014'), ('name', 'Mashona Washington')]
# [('player', 'http://www.wikidata.org/entity/Q54691'), ('name', 'MaliVai Washington')]
# [('player', 'http://www.wikidata.org/entity/Q6783163'), ('name', 'Mashiska Washington')]
# [('player', 'http://www.wikidata.org/entity/Q17750103'), ('name', 'Sara Sorribes Tormo')]
# [('player', 'http://www.wikidata.org/entity/Q1391241'), ('name', 'Yuki Bhambri')]
# [('player', 'http://www.wikidata.org/entity/Q18012636'), ('name', 'Lexie Kenny')]
# [('player', 'http://www.wikidata.org/entity/Q18015494'), ('name', 'Norma Marsh')]
# [('player', 'http://www.wikidata.org/entity/Q18016879'), ('name', 'Susan Hagey')]
# [('player', 'http://www.wikidata.org/entity/Q18018389'), ('name', 'Janet Fallis')]
# [('player', 'http://www.wikidata.org/entity/Q18068750'), ('name', 'Frederick Kemp Ward')]
# [('player', 'http://www.wikidata.org/entity/Q18206583'), ('name', 'Hu Yueyue')]
# [('player', 'http://www.wikidata.org/entity/Q17281094'), ('name', 'Lu Jiajing')]
# [('player', 'http://www.wikidata.org/entity/Q19791650'), ('name', 'Lu Jiaxiang')]
# [('player', 'http://www.wikidata.org/entity/Q19835400'), ('name', 'Bernice van de Velde')]
# [('player', 'http://www.wikidata.org/entity/Q2511279'), ('name', 'Ysaline Bonaventure')]
# [('player', 'http://www.wikidata.org/entity/Q289365'), ('name', 'Karolína Plíšková')]
# [('player', 'http://www.wikidata.org/entity/Q304724'), ('name', 'Guillermo García López')]
# [('player', 'http://www.wikidata.org/entity/Q3210313'), ('name', 'Demi Schuurs')]
# [('player', 'http://www.wikidata.org/entity/Q19896616'), ('name', 'Linda Prenkovic')]
# [('player', 'http://www.wikidata.org/entity/Q19951959'), ('name', 'Josef Caska')]
# [('player', 'http://www.wikidata.org/entity/Q19955631'), ('name', 'Ian Crookenden')]
# [('player', 'http://www.wikidata.org/entity/Q19957245'), ('name', 'Carolin Daniels')]
# [('player', 'http://www.wikidata.org/entity/Q607316'), ('name', 'Mateusz Kowalczyk')]
# [('player', 'http://www.wikidata.org/entity/Q16300924'), ('name', 'Jason Jung')]
# [('player', 'http://www.wikidata.org/entity/Q22677588'), ('name', 'Blake Mott')]
# [('player', 'http://www.wikidata.org/entity/Q22680653'), ('name', 'Julia Jones')]
# [('player', 'http://www.wikidata.org/entity/Q16297666'), ('name', 'Nikoloz Basilashvili')]
# [('player', 'http://www.wikidata.org/entity/Q22679891'), ('name', 'Olga Danilović')]
# [('player', 'http://www.wikidata.org/entity/Q24448039'), ('name', 'Pedro Bernardi')]
# [('player', 'http://www.wikidata.org/entity/Q24450987'), ('name', 'Ulises Blanch')]
# [('player', 'http://www.wikidata.org/entity/Q24452244'), ('name', 'Stefanie Tan')]
# [('player', 'http://www.wikidata.org/entity/Q24474045'), ('name', 'Erika Vogelsang')]
# [('player', 'http://www.wikidata.org/entity/Q24505177'), ('name', 'Mubarak Shannan Zayid')]
# [('player', 'http://www.wikidata.org/entity/Q5181660'), ('name', 'Adam Pavlásek')]
# [('player', 'http://www.wikidata.org/entity/Q5429102'), ('name', 'Facundo Argüello')]
# [('player', 'http://www.wikidata.org/entity/Q16735393'), ('name', 'Federico Gaio')]
# [('player', 'http://www.wikidata.org/entity/Q17381675'), ('name', 'Elise Mertens')]
# [('player', 'http://www.wikidata.org/entity/Q17612134'), ('name', 'Jennifer Brady')]
# [('player', 'http://www.wikidata.org/entity/Q18544740'), ('name', 'Miķelis Lībietis')]
# [('player', 'http://www.wikidata.org/entity/Q1943147'), ('name', 'Peter Polansky')]
# [('player', 'http://www.wikidata.org/entity/Q20708205'), ('name', 'Jamie Loeb')]
# [('player', 'http://www.wikidata.org/entity/Q22957410'), ('name', 'Bianca Andreescu')]
# [('player', 'http://www.wikidata.org/entity/Q239841'), ('name', 'Mandy Minella')]
# [('player', 'http://www.wikidata.org/entity/Q24228674'), ('name', 'Grégoire Barrère')]
# [('player', 'http://www.wikidata.org/entity/Q26405759'), ('name', 'Sander Gillé')]
# [('player', 'http://www.wikidata.org/entity/Q2827366'), ('name', 'Agustín Velotti')]
# [('player', 'http://www.wikidata.org/entity/Q304117'), ('name', 'Alessandro Giannessi')]
# [('player', 'http://www.wikidata.org/entity/Q36778760'), ('name', 'Francesca Di Lorenzo')]
# [('player', 'http://www.wikidata.org/entity/Q369878'), ('name', 'Marsel İlhan')]
# [('player', 'http://www.wikidata.org/entity/Q715261'), ('name', 'Ken Skupski')]
# [('player', 'http://www.wikidata.org/entity/Q28534179'), ('name', 'Hsu Yu-hsiou')]
# [('player', 'http://www.wikidata.org/entity/Q15714673'), ('name', 'Taro Daniel')]
# [('player', 'http://www.wikidata.org/entity/Q29325100'), ('name', 'Kristofer Siimar')]
# [('player', 'http://www.wikidata.org/entity/Q30209961'), ('name', 'Federico Dondo')]
# [('player', 'http://www.wikidata.org/entity/Q30217670'), ('name', 'Whitney Osuigwe')]
# [('player', 'http://www.wikidata.org/entity/Q34055325'), ('name', 'Alessandro Bega')]
# [('player', 'http://www.wikidata.org/entity/Q11662'), ('name', 'Steffi Graf')]
# [('player', 'http://www.wikidata.org/entity/Q17291004'), ('name', 'Sabine Haas')]
# [('player', 'http://www.wikidata.org/entity/Q182736'), ('name', 'Ivan Lendl')]
# [('player', 'http://www.wikidata.org/entity/Q219966'), ('name', 'Thomas Muster')]
# [('player', 'http://www.wikidata.org/entity/Q264493'), ('name', 'Kathy Jordan')]
# [('player', 'http://www.wikidata.org/entity/Q272532'), ('name', 'Marcelo Ríos')]
# [('player', 'http://www.wikidata.org/entity/Q299944'), ('name', 'Arnaud Clément')]
# [('player', 'http://www.wikidata.org/entity/Q3530673'), ('name', 'Tom Bundy')]
# [('player', 'http://www.wikidata.org/entity/Q51066'), ('name', 'István Gulyás')]
# [('player', 'http://www.wikidata.org/entity/Q516293'), ('name', 'Katie Schlukebir')]
# [('player', 'http://www.wikidata.org/entity/Q52453'), ('name', 'Bob Hewitt')]
# [('player', 'http://www.wikidata.org/entity/Q53325'), ('name', 'Arthur Ashe')]
# [('player', 'http://www.wikidata.org/entity/Q53336'), ('name', 'Madison Brengle')]
# [('player', 'http://www.wikidata.org/entity/Q53371'), ('name', 'Dorothy Cheney')]
# [('player', 'http://www.wikidata.org/entity/Q53372'), ('name', 'Julia Cohen')]
# [('player', 'http://www.wikidata.org/entity/Q53390'), ('name', 'Maureen Connolly')]
# [('player', 'http://www.wikidata.org/entity/Q53545'), ('name', 'Jan-Michael Gambill')]
# [('player', 'http://www.wikidata.org/entity/Q53547'), ('name', 'Vitas Gerulaitis')]
# [('player', 'http://www.wikidata.org/entity/Q53553'), ('name', 'Alexa Glatch')]
# [('player', 'http://www.wikidata.org/entity/Q53564'), ('name', 'Doris Hart')]
# [('player', 'http://www.wikidata.org/entity/Q53570'), ('name', 'Barbara Jordan')]
# [('player', 'http://www.wikidata.org/entity/Q54540'), ('name', 'Chuck McKinley')]
# [('player', 'http://www.wikidata.org/entity/Q54542'), ('name', 'Grace Min')]
# [('player', 'http://www.wikidata.org/entity/Q54584'), ('name', 'Andy Roddick')]
# [('player', 'http://www.wikidata.org/entity/Q54663'), ('name', 'Jack Sock')]
# [('player', 'http://www.wikidata.org/entity/Q54670'), ('name', 'Sloane Stephens')]
# [('player', 'http://www.wikidata.org/entity/Q54675'), ('name', 'May Sutton')]
# [('player', 'http://www.wikidata.org/entity/Q61142'), ('name', 'Claudia Kohde-Kilsch')]
# [('player', 'http://www.wikidata.org/entity/Q62174'), ('name', 'Hilde Krahwinkel Sperling')]
# [('player', 'http://www.wikidata.org/entity/Q63080'), ('name', 'Julian Reister')]
# [('player', 'http://www.wikidata.org/entity/Q63289'), ('name', 'Dinah Pfizenmaier')]
# [('player', 'http://www.wikidata.org/entity/Q63355'), ('name', 'David Prinosil')]
# [('player', 'http://www.wikidata.org/entity/Q63383'), ('name', 'Karsten Braasch')]
# [('player', 'http://www.wikidata.org/entity/Q7347560'), ('name', 'Robert McKinley')]
# [('player', 'http://www.wikidata.org/entity/Q7407'), ('name', 'Andre Agassi')]
# [('player', 'http://www.wikidata.org/entity/Q742332'), ('name', 'Harry Hopman')]
# [('player', 'http://www.wikidata.org/entity/Q76334'), ('name', 'Boris Becker')]
# [('player', 'http://www.wikidata.org/entity/Q16221584'), ('name', 'Yoky Matsuoka')]
# [('player', 'http://www.wikidata.org/entity/Q85093'), ('name', 'Arthur Zborzil')]
# [('player', 'http://www.wikidata.org/entity/Q85117'), ('name', 'Christian Saceanu')]
# [('player', 'http://www.wikidata.org/entity/Q89868'), ('name', 'Silke Meier')]
# [('player', 'http://www.wikidata.org/entity/Q91206'), ('name', 'Tore Meinecke')]
# [('player', 'http://www.wikidata.org/entity/Q91615'), ('name', 'Peter Gojowczyk')]
# [('player', 'http://www.wikidata.org/entity/Q132147'), ('name', 'Sania Mirza')]
# [('player', 'http://www.wikidata.org/entity/Q162487'), ('name', 'Cédric Pioline')]
# [('player', 'http://www.wikidata.org/entity/Q179364'), ('name', 'Andrei Pavel')]
# [('player', 'http://www.wikidata.org/entity/Q229093'), ('name', 'Virginia Ruano Pascual')]
# [('player', 'http://www.wikidata.org/entity/Q487182'), ('name', 'Anastasia Pavlyuchenkova')]
# [('player', 'http://www.wikidata.org/entity/Q102052'), ('name', 'Wolfgang Boos')]
# [('player', 'http://www.wikidata.org/entity/Q16018157'), ('name', 'Gilbert Agnew Hunt')]
# [('player', 'http://www.wikidata.org/entity/Q204101'), ('name', 'Marie Wagner')]
# [('player', 'http://www.wikidata.org/entity/Q2350423'), ('name', 'Ashok Amritraj')]
# [('player', 'http://www.wikidata.org/entity/Q241637'), ('name', 'Alexandra Stevenson')]
# [('player', 'http://www.wikidata.org/entity/Q552529'), ('name', 'Ted Gärdestad')]
# [('player', 'http://www.wikidata.org/entity/Q229831'), ('name', 'Nathalie Dechy')]
# [('player', 'http://www.wikidata.org/entity/Q23759136'), ('name', 'Julien Hoferlin')]
# [('player', 'http://www.wikidata.org/entity/Q247192'), ('name', 'Valeriya Solovyeva')]
# [('player', 'http://www.wikidata.org/entity/Q254232'), ('name', 'Alicja Rosolska')]
# [('player', 'http://www.wikidata.org/entity/Q254260'), ('name', 'María Vento-Kabchi')]
# [('player', 'http://www.wikidata.org/entity/Q254328'), ('name', 'Darya Kustova')]
# [('player', 'http://www.wikidata.org/entity/Q254756'), ('name', 'Vitalia Diatchenko')]
# [('player', 'http://www.wikidata.org/entity/Q258716'), ('name', 'Stanley Matthews')]
# [('player', 'http://www.wikidata.org/entity/Q259276'), ('name', 'Akiko Morigami')]
# [('player', 'http://www.wikidata.org/entity/Q262027'), ('name', 'Maud Watson')]
# [('player', 'http://www.wikidata.org/entity/Q266506'), ('name', 'Kea Bouman')]
# [('player', 'http://www.wikidata.org/entity/Q267328'), ('name', 'Antonio Zugarelli')]
# [('player', 'http://www.wikidata.org/entity/Q270408'), ('name', 'Andrea Temesvári')]
# [('player', 'http://www.wikidata.org/entity/Q270414'), ('name', 'Anne Smith')]
# [('player', 'http://www.wikidata.org/entity/Q270967'), ('name', 'Dominique Monami')]
# [('player', 'http://www.wikidata.org/entity/Q298542'), ('name', 'Daniel Nestor')]
# [('player', 'http://www.wikidata.org/entity/Q3175568'), ('name', 'Lilian Watson')]
# [('player', 'http://www.wikidata.org/entity/Q47330989'), ('name', 'Tímea Visontai')]
# [('player', 'http://www.wikidata.org/entity/Q5239547'), ('name', 'David Schneider')]
# [('player', 'http://www.wikidata.org/entity/Q301480'), ('name', 'Julian Myrick')]
# [('player', 'http://www.wikidata.org/entity/Q305043'), ('name', 'Thomas Shimada')]
# [('player', 'http://www.wikidata.org/entity/Q310380'), ('name', 'Jonas Björkman')]
# [('player', 'http://www.wikidata.org/entity/Q311222'), ('name', 'Kei Nishikori')]
# [('player', 'http://www.wikidata.org/entity/Q318569'), ('name', 'Manuel Orantes')]
# [('player', 'http://www.wikidata.org/entity/Q715134'), ('name', 'Brad Gilbert')]
# [('player', 'http://www.wikidata.org/entity/Q1345408'), ('name', 'Alberto Mancini')]
# [('player', 'http://www.wikidata.org/entity/Q232435'), ('name', 'Jill Craybas')]
# [('player', 'http://www.wikidata.org/entity/Q232575'), ('name', 'Marina Erakovic')]
# [('player', 'http://www.wikidata.org/entity/Q335345'), ('name', 'Jonathan Erlich')]
# [('player', 'http://www.wikidata.org/entity/Q345626'), ('name', 'Łukasz Kubot')]
# [('player', 'http://www.wikidata.org/entity/Q355308'), ('name', 'Karol Beck')]
# [('player', 'http://www.wikidata.org/entity/Q357354'), ('name', 'Adine Masson')]
# [('player', 'http://www.wikidata.org/entity/Q358651'), ('name', 'Pablo Cuevas')]
# [('player', 'http://www.wikidata.org/entity/Q361676'), ('name', 'Younes El Aynaoui')]
# [('player', 'http://www.wikidata.org/entity/Q365139'), ('name', 'William Renshaw')]
# [('player', 'http://www.wikidata.org/entity/Q367978'), ('name', 'Santiago Ventura')]
# [('player', 'http://www.wikidata.org/entity/Q368775'), ('name', 'Gerardo Vacarezza')]
# [('player', 'http://www.wikidata.org/entity/Q369243'), ('name', 'Miloslav Mečíř')]
# [('player', 'http://www.wikidata.org/entity/Q505764'), ('name', 'Ernest Renshaw')]
# [('player', 'http://www.wikidata.org/entity/Q6777779'), ('name', 'Martín Cuevas')]
# [('player', 'http://www.wikidata.org/entity/Q6860514'), ('name', 'Miloslav Mečíř, Jr.')]
# [('player', 'http://www.wikidata.org/entity/Q1373440'), ('name', 'Scott Davis')]
# [('player', 'http://www.wikidata.org/entity/Q2325022'), ('name', 'John Lucas II')]
# [('player', 'http://www.wikidata.org/entity/Q2939349'), ('name', 'Carlos Ferrer Salat')]
# [('player', 'http://www.wikidata.org/entity/Q371971'), ('name', 'Henri Cochet')]
# [('player', 'http://www.wikidata.org/entity/Q376581'), ('name', 'Jack Crawford')]
# [('player', 'http://www.wikidata.org/entity/Q427379'), ('name', 'Ronald Thomas')]
# [('player', 'http://www.wikidata.org/entity/Q432540'), ('name', 'Sigrid Fick')]
# [('player', 'http://www.wikidata.org/entity/Q432791'), ('name', 'Grace Roosevelt')]
# [('player', 'http://www.wikidata.org/entity/Q436000'), ('name', 'Ellen Roosevelt')]
# [('player', 'http://www.wikidata.org/entity/Q520836'), ('name', 'Michail Elgin')]
# [('player', 'http://www.wikidata.org/entity/Q54543'), ('name', 'Helen Wills')]
# [('player', 'http://www.wikidata.org/entity/Q259328'), ('name', 'Rosemary Casals')]
# [('player', 'http://www.wikidata.org/entity/Q2698644'), ('name', 'Anand Amritraj')]
# [('player', 'http://www.wikidata.org/entity/Q375938'), ('name', 'Adriano Panatta')]
# [('player', 'http://www.wikidata.org/entity/Q42675013'), ('name', 'Clara Tauson')]
# [('player', 'http://www.wikidata.org/entity/Q460552'), ('name', 'Laurence Tieleman')]
# [('player', 'http://www.wikidata.org/entity/Q461080'), ('name', 'Sharon Walsh')]
# [('player', 'http://www.wikidata.org/entity/Q461088'), ('name', 'Myrtle McAteer')]
# [('player', 'http://www.wikidata.org/entity/Q461338'), ('name', 'Amélie Cocheteux')]
# [('player', 'http://www.wikidata.org/entity/Q462445'), ('name', 'Marcos Daniel')]
# [('player', 'http://www.wikidata.org/entity/Q462457'), ('name', 'Frank Dancevic')]
# [('player', 'http://www.wikidata.org/entity/Q463485'), ('name', 'Loïc Courteau')]
# [('player', 'http://www.wikidata.org/entity/Q463982'), ('name', 'Steve DeVries')]
# [('player', 'http://www.wikidata.org/entity/Q464621'), ('name', 'Rodolphe Gilbert')]
# [('player', 'http://www.wikidata.org/entity/Q464779'), ('name', 'Claudio Panatta')]
# [('player', 'http://www.wikidata.org/entity/Q467476'), ('name', 'Betty Nuthall')]
# [('player', 'http://www.wikidata.org/entity/Q467725'), ('name', 'Phyllis Covell')]
# [('player', 'http://www.wikidata.org/entity/Q468309'), ('name', 'Vijay Amritraj')]
# [('player', 'http://www.wikidata.org/entity/Q469531'), ('name', 'Helga Niessen Masthoff')]
# [('player', 'http://www.wikidata.org/entity/Q475591'), ('name', 'Michael Tauson')]
# [('player', 'http://www.wikidata.org/entity/Q635131'), ('name', 'James Brown')]
# [('player', 'http://www.wikidata.org/entity/Q134720'), ('name', 'Martina Hingis')]
# [('player', 'http://www.wikidata.org/entity/Q16475'), ('name', 'Mats Wilander')]
# [('player', 'http://www.wikidata.org/entity/Q507351'), ('name', 'Vincent Millot')]
# [('player', 'http://www.wikidata.org/entity/Q510016'), ('name', 'Donna Faber')]
# [('player', 'http://www.wikidata.org/entity/Q512302'), ('name', 'Ellis Ferreira')]
# [('player', 'http://www.wikidata.org/entity/Q512645'), ('name', 'Teodora Mirčić')]
# [('player', 'http://www.wikidata.org/entity/Q512728'), ('name', 'Bobby Reynolds')]
# [('player', 'http://www.wikidata.org/entity/Q515677'), ('name', 'Matthew Ebden')]
# [('player', 'http://www.wikidata.org/entity/Q516701'), ('name', 'Eva Švíglerová')]
# [('player', 'http://www.wikidata.org/entity/Q516799'), ('name', 'Ginger Helgeson-Nielsen')]
# [('player', 'http://www.wikidata.org/entity/Q516872'), ('name', 'Gretchen Rush')]
# [('player', 'http://www.wikidata.org/entity/Q518931'), ('name', 'André Gobert')]
# [('player', 'http://www.wikidata.org/entity/Q519294'), ('name', 'Travis Rettenmaier')]
# [('player', 'http://www.wikidata.org/entity/Q521302'), ('name', 'Wilmer Allison')]
# [('player', 'http://www.wikidata.org/entity/Q523733'), ('name', 'Andrée Gremillet')]
# [('player', 'http://www.wikidata.org/entity/Q525369'), ('name', 'Francky Wardan')]
# [('player', 'http://www.wikidata.org/entity/Q525464'), ('name', 'Marjorie Gladman')]
# [('player', 'http://www.wikidata.org/entity/Q526263'), ('name', 'Carolin Babcock')]
# [('player', 'http://www.wikidata.org/entity/Q526338'), ('name', 'Ethel Bliss Platt')]
# [('player', 'http://www.wikidata.org/entity/Q526415'), ('name', 'Harriet Butler')]
# [('player', 'http://www.wikidata.org/entity/Q530882'), ('name', 'Heinrich Schomburgk')]
# [('player', 'http://www.wikidata.org/entity/Q11685'), ('name', 'Kim Clijsters')]
# [('player', 'http://www.wikidata.org/entity/Q221908'), ('name', 'Yannick Noah')]
# [('player', 'http://www.wikidata.org/entity/Q229116'), ('name', 'Katarina Srebotnik')]
# [('player', 'http://www.wikidata.org/entity/Q29743947'), ('name', 'Léopold de Borman')]
# [('player', 'http://www.wikidata.org/entity/Q29783944'), ('name', 'Geneviève de Borman')]
# [('player', 'http://www.wikidata.org/entity/Q29785125'), ('name', 'Myriam de Borman')]
# [('player', 'http://www.wikidata.org/entity/Q502002'), ('name', 'Andrei Chesnokov')]
# [('player', 'http://www.wikidata.org/entity/Q556488'), ('name', 'Paul de Borman')]
# [('player', 'http://www.wikidata.org/entity/Q556709'), ('name', 'Mathieu Montcourt')]
# [('player', 'http://www.wikidata.org/entity/Q559777'), ('name', 'John-Patrick Smith')]
# [('player', 'http://www.wikidata.org/entity/Q565913'), ('name', 'Anne de Borman')]
# [('player', 'http://www.wikidata.org/entity/Q578931'), ('name', 'Ivanna Madruga')]
# [('player', 'http://www.wikidata.org/entity/Q970533'), ('name', 'João Souza')]
# [('player', 'http://www.wikidata.org/entity/Q988904'), ('name', 'Elke Clijsters')]
# [('player', 'http://www.wikidata.org/entity/Q15269'), ('name', 'Jelena Janković')]
# [('player', 'http://www.wikidata.org/entity/Q2443685'), ('name', 'Shuko Aoyama')]
# [('player', 'http://www.wikidata.org/entity/Q335333'), ('name', 'Mark Knowles')]
# [('player', 'http://www.wikidata.org/entity/Q57559'), ('name', 'Anna-Lena Grönefeld')]
# [('player', 'http://www.wikidata.org/entity/Q634844'), ('name', 'Elena Vesnina')]
# [('player', 'http://www.wikidata.org/entity/Q469324'), ('name', 'Sjeng Schalken')]
# [('player', 'http://www.wikidata.org/entity/Q691217'), ('name', 'Arnaud Boetsch')]
# [('player', 'http://www.wikidata.org/entity/Q212833'), ('name', 'Gilles Simon')]
# [('player', 'http://www.wikidata.org/entity/Q2444159'), ('name', "Élisabeth d'Ayen")]
# [('player', 'http://www.wikidata.org/entity/Q2447911'), ('name', 'Olivier Patience')]
# [('player', 'http://www.wikidata.org/entity/Q2469802'), ('name', 'Arnold Watson Hutton')]
# [('player', 'http://www.wikidata.org/entity/Q335326'), ('name', 'Paul Hanley')]
# [('player', 'http://www.wikidata.org/entity/Q355305'), ('name', 'Lukáš Dlouhý')]
# [('player', 'http://www.wikidata.org/entity/Q27755341'), ('name', 'Dimítrios Kanellopoúlos')]
# [('player', 'http://www.wikidata.org/entity/Q2837905'), ('name', 'Allen Morris')]
# [('player', 'http://www.wikidata.org/entity/Q2847008'), ('name', 'András Ádám-Stolpa')]
# [('player', 'http://www.wikidata.org/entity/Q2849052'), ('name', 'Andy Andrews')]
# [('player', 'http://www.wikidata.org/entity/Q2849415'), ('name', 'Angelikí Kanellopoúlou')]
# [('player', 'http://www.wikidata.org/entity/Q67074118'), ('name', 'Roger Danet')]
# [('player', 'http://www.wikidata.org/entity/Q6761562'), ('name', 'Maria Sakkari')]
# [('player', 'http://www.wikidata.org/entity/Q2926443'), ('name', 'Bruce Manson')]
# [('player', 'http://www.wikidata.org/entity/Q2928232'), ('name', 'Bunny Bruning')]
# [('player', 'http://www.wikidata.org/entity/Q2935183'), ('name', 'Cammy MacGregor')]
# [('player', 'http://www.wikidata.org/entity/Q2939340'), ('name', 'Carlos Fernandes')]
# [('player', 'http://www.wikidata.org/entity/Q2940058'), ('name', 'Caroline Stoll')]
# [('player', 'http://www.wikidata.org/entity/Q2958928'), ('name', 'Charles Donohoe')]
# [('player', 'http://www.wikidata.org/entity/Q2959308'), ('name', 'Charles Hare')]
# [('player', 'http://www.wikidata.org/entity/Q3008813'), ('name', 'Cynthia MacGregor')]
# [('player', 'http://www.wikidata.org/entity/Q3148788'), ('name', 'Ilou Lonfo')]
# [('player', 'http://www.wikidata.org/entity/Q3160954'), ('name', 'James Brink')]
# [('player', 'http://www.wikidata.org/entity/Q3161924'), ('name', 'Janet Newberry')]
# [('player', 'http://www.wikidata.org/entity/Q3162019'), ('name', 'Janine Thompson')]
# [('player', 'http://www.wikidata.org/entity/Q3182361'), ('name', 'John Richardson')]
# [('player', 'http://www.wikidata.org/entity/Q180872'), ('name', 'Amélie Mauresmo')]
# [('player', 'http://www.wikidata.org/entity/Q3237546'), ('name', 'Li Fang')]
# [('player', 'http://www.wikidata.org/entity/Q3241337'), ('name', 'Linda Gates')]
# [('player', 'http://www.wikidata.org/entity/Q3242430'), ('name', 'Lisa McShea')]
# [('player', 'http://www.wikidata.org/entity/Q5125175'), ('name', 'Claire Curran')]
# [('player', 'http://www.wikidata.org/entity/Q5129282'), ('name', 'Claudia Williams')]
# [('player', 'http://www.wikidata.org/entity/Q12193601'), ('name', 'Samantha Murray')]
# [('player', 'http://www.wikidata.org/entity/Q5239027'), ('name', 'David Rice')]
# [('player', 'http://www.wikidata.org/entity/Q5246176'), ('name', 'Dean Goldfine')]
# [('player', 'http://www.wikidata.org/entity/Q5252686'), ('name', 'Dejan Petrovic')]
# [('player', 'http://www.wikidata.org/entity/Q5274886'), ('name', 'Diego del Rio')]
# [('player', 'http://www.wikidata.org/entity/Q5284058'), ('name', 'Divij Sharan')]
# [('player', 'http://www.wikidata.org/entity/Q5886813'), ('name', 'Kjell Johansson')]
# [('player', 'http://www.wikidata.org/entity/Q3293504'), ('name', 'Mario Martínez')]
# [('player', 'http://www.wikidata.org/entity/Q5984476'), ('name', 'Ibrahim Badreldin-Sayed')]
# [('player', 'http://www.wikidata.org/entity/Q6008377'), ('name', 'Imre Zichy')]
# [('player', 'http://www.wikidata.org/entity/Q6009648'), ('name', 'Melissa Torres Sandoval')]
# [('player', 'http://www.wikidata.org/entity/Q6042102'), ('name', 'Nicolás Barrientos')]
# 500

# %%
# Counting all triplets who have tennis player (wd:Q10833314) as profession (wdt:P106)
queryString = """
SELECT (COUNT(*) AS ?totTennisPlayers)
WHERE {
   # bind something
   wd:Q10833314 ^wdt:P106 ?player .
   # get the label
   # ?player sc:name ?name.
}
LIMIT 500
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('totTennisPlayers', '11139')]
# 1

# %%
# Counting all triplets who have tennis player (wd:Q10833314) as profession (wdt:P106) and checking their type. Goal only humans.
queryString = """
SELECT ?instanceOf ?instanceName (COUNT(?player) AS ?howMany)
WHERE {
   # bind something
   wd:Q10833314 ^wdt:P106 ?player .
   # ?player wdt:P31 ?instanceOf .
   # get the label
   # ?instanceOf sc:name ?instanceName .
}
GROUP BY ?instanceOf ?instanceName
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('instanceOf', 'http://www.wikidata.org/entity/Q5'), ('instanceName', 'human'), ('howMany', '11202')]
# [('instanceOf', 'http://www.wikidata.org/entity/Q15773317'), ('instanceName', 'television character'), ('howMany', '1')]
# [('instanceOf', 'http://www.wikidata.org/entity/Q1114461'), ('instanceName', 'comics character'), ('howMany', '1')]
# [('instanceOf', 'http://www.wikidata.org/entity/Q15632617'), ('instanceName', 'fictional human'), ('howMany', '2')]
# [('instanceOf', 'http://www.wikidata.org/entity/Q95074'), ('instanceName', 'fictional character'), ('howMany', '1')]
# [('instanceOf', 'http://www.wikidata.org/entity/Q4359230'), ('instanceName', 'characters from James Bond series'), ('howMany', '1')]
# [('instanceOf', 'http://www.wikidata.org/entity/Q22074477'), ('instanceName', 'cyborg in a work of fiction'), ('howMany', '1')]
# [('instanceOf', 'http://www.wikidata.org/entity/Q17362920'), ('instanceName', 'Wikimedia duplicated page'), ('howMany', '1')]
# [('instanceOf', 'http://www.wikidata.org/entity/Q15711870'), ('instanceName', 'animated character'), ('howMany', '1')]
# 9

# %%
# [RE] Counting all triplets who have tennis player (wd:Q10833314) as profession (wdt:P106)
# TODO: problem totTennisPlayers count is 11139 meanwhile the counting all instanceOf the players is over 11202 -->ARE NOT DISTINCT!!!!
#       NOT excluding mutually
queryString = """
SELECT (COUNT(*) AS ?totTennisPlayers)
WHERE {
   # bind something
   wd:Q10833314 ^wdt:P106 ?player .
   # get the label
   # ?player sc:name ?name.
}
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('totTennisPlayers', '11139')]
# 1

# %%
# Find all tennis players (wd:Q10833314), and only those who are instanceOf (wdt:P31) of HUMANS (wd:Q5)
queryString = """
SELECT DISTINCT ?player ?name
WHERE {
   # bind something
   wd:Q10833314 ^wdt:P106 ?player .
   # ?player wdt:P31 wd:Q5 .
   # get the label
   # ?player sc:name ?name.
}
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('player', 'http://www.wikidata.org/entity/Q1683632'), ('name', 'Jaroslav Navrátil')]
# [('player', 'http://www.wikidata.org/entity/Q138094'), ('name', 'Anna Karolína Schmiedlová')]
# [('player', 'http://www.wikidata.org/entity/Q15197746'), ('name', 'Wesley Koolhof')]
# [('player', 'http://www.wikidata.org/entity/Q1558013'), ('name', 'Pierre Barthès')]
# [('player', 'http://www.wikidata.org/entity/Q15849678'), ('name', 'Sue Partridge')]
# [('player', 'http://www.wikidata.org/entity/Q15880574'), ('name', 'Paul Oosterbaan')]
# [('player', 'http://www.wikidata.org/entity/Q240837'), ('name', 'Rika Fujiwara')]
# [('player', 'http://www.wikidata.org/entity/Q4134097'), ('name', 'Margarita Gasparyan')]
# [('player', 'http://www.wikidata.org/entity/Q589611'), ('name', 'Philippe Chatrier')]
# [('player', 'http://www.wikidata.org/entity/Q16009513'), ('name', 'James Bayley')]
# [('player', 'http://www.wikidata.org/entity/Q16023406'), ('name', 'Samuel T. Chase')]
# [('player', 'http://www.wikidata.org/entity/Q16063202'), ('name', 'Agnete Goldschmidt')]
# [('player', 'http://www.wikidata.org/entity/Q16065254'), ('name', 'Thorkil Hillerup')]
# [('player', 'http://www.wikidata.org/entity/Q16067006'), ('name', 'Lois Moyes Bickle')]
# [('player', 'http://www.wikidata.org/entity/Q1660141'), ('name', 'Perry Jones')]
# [('player', 'http://www.wikidata.org/entity/Q299959'), ('name', 'Eileen Bennett Whittingstall')]
# [('player', 'http://www.wikidata.org/entity/Q16203224'), ('name', 'Frederick Campbell Colston')]
# [('player', 'http://www.wikidata.org/entity/Q16204467'), ('name', 'Andrew Drew')]
# [('player', 'http://www.wikidata.org/entity/Q16208155'), ('name', 'Chris Forney')]
# [('player', 'http://www.wikidata.org/entity/Q16210951'), ('name', 'N. M. Smith')]
# 20

# %%
# COUNTING all tennis players (wd:Q10833314), and only those who are instanceOf (wdt:P31) of HUMANS (wd:Q5)
queryString = """
SELECT (COUNT(*) AS ?totTennisPlayers)
WHERE {
   # bind something
   wd:Q10833314 ^wdt:P106 ?player .
   # ?player wdt:P31 wd:Q5 .
   # get the label
   # ?player sc:name ?name.
}
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('totTennisPlayers', '11136')]
# 1

# %%
# COUNTING all tennis players (wd:Q10833314), and only those who are instanceOf (wdt:P31) of HUMANS (wd:Q5)
# found that 3 were not HUMANs but something else, lets find who they are
queryString = """
SELECT DISTINCT ?player ?name ?instanceOf
WHERE {
   # bind something
   wd:Q10833314 ^wdt:P106 ?player .
   # ?player wdt:P31 ?instanceOf .
   # get the label
   # ?player sc:name ?name.
   
   #Excluding HUMANs
   FILTER (?instanceOf != wd:Q5) .
}
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('player', 'http://www.wikidata.org/entity/Q6123929'), ('name', 'Jaime Sommers'), ('instanceOf', 'http://www.wikidata.org/entity/Q95074')]
# [('player', 'http://www.wikidata.org/entity/Q6123929'), ('name', 'Jaime Sommers'), ('instanceOf', 'http://www.wikidata.org/entity/Q22074477')]
# [('player', 'http://www.wikidata.org/entity/Q6123929'), ('name', 'Jaime Sommers'), ('instanceOf', 'http://www.wikidata.org/entity/Q15773317')]
# [('player', 'http://www.wikidata.org/entity/Q2721145'), ('name', 'Bette Kane'), ('instanceOf', 'http://www.wikidata.org/entity/Q15711870')]
# [('player', 'http://www.wikidata.org/entity/Q2721145'), ('name', 'Bette Kane'), ('instanceOf', 'http://www.wikidata.org/entity/Q1114461')]
# [('player', 'http://www.wikidata.org/entity/Q2721145'), ('name', 'Bette Kane'), ('instanceOf', 'http://www.wikidata.org/entity/Q15632617')]
# [('player', 'http://www.wikidata.org/entity/Q10390567'), ('name', 'Vijay'), ('instanceOf', 'http://www.wikidata.org/entity/Q15632617')]
# [('player', 'http://www.wikidata.org/entity/Q10390567'), ('name', 'Vijay'), ('instanceOf', 'http://www.wikidata.org/entity/Q4359230')]
# 8

# %%
# COUNTING all tennis players (wd:Q10833314), and only those who are instanceOf (wdt:P31) of HUMANS (wd:Q5)
# found that 3 were not HUMANs but something else, lets find who they are WITH instanceName
queryString = """
SELECT DISTINCT ?player ?name ?instanceOf ?instanceName
WHERE {
   # bind something
   wd:Q10833314 ^wdt:P106 ?player .
   # ?player wdt:P31 ?instanceOf .
   # get the label
   # ?player sc:name ?name.
   # ?instanceOf sc:name ?instanceName .
   
   #Excluding HUMANs
   FILTER (?instanceOf != wd:Q5) .
}
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('player', 'http://www.wikidata.org/entity/Q6123929'), ('name', 'Jaime Sommers'), ('instanceOf', 'http://www.wikidata.org/entity/Q95074'), ('instanceName', 'fictional character')]
# [('player', 'http://www.wikidata.org/entity/Q6123929'), ('name', 'Jaime Sommers'), ('instanceOf', 'http://www.wikidata.org/entity/Q22074477'), ('instanceName', 'cyborg in a work of fiction')]
# [('player', 'http://www.wikidata.org/entity/Q6123929'), ('name', 'Jaime Sommers'), ('instanceOf', 'http://www.wikidata.org/entity/Q15773317'), ('instanceName', 'television character')]
# [('player', 'http://www.wikidata.org/entity/Q2721145'), ('name', 'Bette Kane'), ('instanceOf', 'http://www.wikidata.org/entity/Q15632617'), ('instanceName', 'fictional human')]
# [('player', 'http://www.wikidata.org/entity/Q2721145'), ('name', 'Bette Kane'), ('instanceOf', 'http://www.wikidata.org/entity/Q1114461'), ('instanceName', 'comics character')]
# [('player', 'http://www.wikidata.org/entity/Q2721145'), ('name', 'Bette Kane'), ('instanceOf', 'http://www.wikidata.org/entity/Q15711870'), ('instanceName', 'animated character')]
# [('player', 'http://www.wikidata.org/entity/Q10390567'), ('name', 'Vijay'), ('instanceOf', 'http://www.wikidata.org/entity/Q15632617'), ('instanceName', 'fictional human')]
# [('player', 'http://www.wikidata.org/entity/Q10390567'), ('name', 'Vijay'), ('instanceOf', 'http://www.wikidata.org/entity/Q4359230'), ('instanceName', 'characters from James Bond series')]
# 8

# %%
# BGP for *tennis player* (wd:Q10833314)
queryString = """
SELECT DISTINCT ?p ?o
WHERE {
   # bind something
   wd:Q10833314 ?p ?o.
}
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), ('o', 'http://wikiba.se/ontology#Item')]
# [('p', 'http://www.wikidata.org/prop/direct-normalized/P1014'), ('o', 'http://vocab.getty.edu/aat/300389804')]
# [('p', 'http://www.wikidata.org/prop/direct-normalized/P227'), ('o', 'https://d-nb.info/gnd/4184716-7')]
# [('p', 'http://www.wikidata.org/prop/direct-normalized/P244'), ('o', 'https://id.loc.gov/authorities/names/sh85133910')]
# [('p', 'http://www.wikidata.org/prop/direct-normalized/P268'), ('o', 'http://data.bnf.fr/ark:/12148/cb119355211#about')]
# [('p', 'http://www.wikidata.org/prop/direct-normalized/P508'), ('o', 'http://purl.org/bncf/tid/4011')]
# [('p', 'http://www.wikidata.org/prop/direct-normalized/P646'), ('o', 'http://g.co/kg/m/02xhr73')]
# [('p', 'http://www.wikidata.org/prop/direct/P1014'), ('o', '300389804')]
# [('p', 'http://www.wikidata.org/prop/direct/P1296'), ('o', '0145573')]
# [('p', 'http://www.wikidata.org/prop/direct/P1296'), ('o', '0275837')]
# [('p', 'http://www.wikidata.org/prop/direct/P1424'), ('o', 'http://www.wikidata.org/entity/Q6053701')]
# [('p', 'http://www.wikidata.org/prop/direct/P1552'), ('o', 'http://www.wikidata.org/entity/Q48295870')]
# [('p', 'http://www.wikidata.org/prop/direct/P1709'), ('o', 'http://dbpedia.org/ontology/TennisPlayer')]
# [('p', 'http://www.wikidata.org/prop/direct/P18'), ('o', 'http://commons.wikimedia.org/wiki/Special:FilePath/%D8%AA%D9%86%D9%8A%D8%B3%D9%86%D8%A7.jpg')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('o', 'http://www.wikidata.org/entity/P3698')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('o', 'http://www.wikidata.org/entity/P2641')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('o', 'http://www.wikidata.org/entity/P2642')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('o', 'http://www.wikidata.org/entity/P3363')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('o', 'http://www.wikidata.org/entity/P3670')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('o', 'http://www.wikidata.org/entity/P4402')]
# 20

# %%
# BGP for *tennis player* (wd:Q10833314) extending LIMIT to 50
queryString = """
SELECT DISTINCT ?p ?o
WHERE {
   # bind something
   wd:Q10833314 ?p ?o.
}
LIMIT 50
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), ('o', 'http://wikiba.se/ontology#Item')]
# [('p', 'http://www.wikidata.org/prop/direct-normalized/P1014'), ('o', 'http://vocab.getty.edu/aat/300389804')]
# [('p', 'http://www.wikidata.org/prop/direct-normalized/P227'), ('o', 'https://d-nb.info/gnd/4184716-7')]
# [('p', 'http://www.wikidata.org/prop/direct-normalized/P244'), ('o', 'https://id.loc.gov/authorities/names/sh85133910')]
# [('p', 'http://www.wikidata.org/prop/direct-normalized/P268'), ('o', 'http://data.bnf.fr/ark:/12148/cb119355211#about')]
# [('p', 'http://www.wikidata.org/prop/direct-normalized/P508'), ('o', 'http://purl.org/bncf/tid/4011')]
# [('p', 'http://www.wikidata.org/prop/direct-normalized/P646'), ('o', 'http://g.co/kg/m/02xhr73')]
# [('p', 'http://www.wikidata.org/prop/direct/P1014'), ('o', '300389804')]
# [('p', 'http://www.wikidata.org/prop/direct/P1296'), ('o', '0145573')]
# [('p', 'http://www.wikidata.org/prop/direct/P1296'), ('o', '0275837')]
# [('p', 'http://www.wikidata.org/prop/direct/P1424'), ('o', 'http://www.wikidata.org/entity/Q6053701')]
# [('p', 'http://www.wikidata.org/prop/direct/P1552'), ('o', 'http://www.wikidata.org/entity/Q48295870')]
# [('p', 'http://www.wikidata.org/prop/direct/P1709'), ('o', 'http://dbpedia.org/ontology/TennisPlayer')]
# [('p', 'http://www.wikidata.org/prop/direct/P18'), ('o', 'http://commons.wikimedia.org/wiki/Special:FilePath/%D8%AA%D9%86%D9%8A%D8%B3%D9%86%D8%A7.jpg')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('o', 'http://www.wikidata.org/entity/P3698')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('o', 'http://www.wikidata.org/entity/P2641')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('o', 'http://www.wikidata.org/entity/P2642')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('o', 'http://www.wikidata.org/entity/P3363')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('o', 'http://www.wikidata.org/entity/P3670')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('o', 'http://www.wikidata.org/entity/P4402')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('o', 'http://www.wikidata.org/entity/P4503')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('o', 'http://www.wikidata.org/entity/P4544')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('o', 'http://www.wikidata.org/entity/P536')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('o', 'http://www.wikidata.org/entity/P552')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('o', 'http://www.wikidata.org/entity/P597')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('o', 'http://www.wikidata.org/entity/P599')]
# [('p', 'http://www.wikidata.org/prop/direct/P227'), ('o', '4184716-7')]
# [('p', 'http://www.wikidata.org/prop/direct/P2354'), ('o', 'http://www.wikidata.org/entity/Q2050412')]
# [('p', 'http://www.wikidata.org/prop/direct/P2354'), ('o', 'http://www.wikidata.org/entity/Q3238475')]
# [('p', 'http://www.wikidata.org/prop/direct/P2354'), ('o', 'http://www.wikidata.org/entity/Q3249741')]
# [('p', 'http://www.wikidata.org/prop/direct/P244'), ('o', 'sh85133910')]
# [('p', 'http://www.wikidata.org/prop/direct/P268'), ('o', '119355211')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('o', 'http://www.wikidata.org/entity/Q18536342')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('o', 'http://www.wikidata.org/entity/Q2066131')]
# [('p', 'http://www.wikidata.org/prop/direct/P2888'), ('o', 'http://imagenet.stanford.edu/synset?wnid=n10701180')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('o', 'http://www.wikidata.org/entity/Q28640')]
# [('p', 'http://www.wikidata.org/prop/direct/P3417'), ('o', 'Tennis-Players')]
# [('p', 'http://www.wikidata.org/prop/direct/P373'), ('o', 'Tennis players')]
# [('p', 'http://www.wikidata.org/prop/direct/P425'), ('o', 'http://www.wikidata.org/entity/Q56054951')]
# [('p', 'http://www.wikidata.org/prop/direct/P425'), ('o', 'http://www.wikidata.org/entity/Q847')]
# [('p', 'http://www.wikidata.org/prop/direct/P425'), ('o', 'http://www.wikidata.org/entity/Q17988507')]
# [('p', 'http://www.wikidata.org/prop/direct/P508'), ('o', '4011')]
# [('p', 'http://www.wikidata.org/prop/direct/P6186'), ('o', 'http://www.wikidata.org/entity/Q17477038')]
# [('p', 'http://www.wikidata.org/prop/direct/P641'), ('o', 'http://www.wikidata.org/entity/Q847')]
# [('p', 'http://www.wikidata.org/prop/direct/P646'), ('o', '/m/02xhr73')]
# [('p', 'http://www.wikidata.org/prop/direct/P8814'), ('o', '10720829-n')]
# [('p', 'http://www.wikidata.org/prop/direct/P910'), ('o', 'http://www.wikidata.org/entity/Q4853725')]
# [('p', 'http://schema.org/name'), ('o', 'tennis player')]
# 48

# %% [markdown]
# #### NOW I realised that the task was not asking all the players but only the BGP for *tennis player*.

# %%
# TASK1: Identify the BGP for *tennis player*
# With this query I'm trying to find Roger Federer's (wd:Q1426) profession (wdt:P106) -> tennis player
queryString = """
SELECT DISTINCT ?profession ?name
WHERE {
   # bind something
   wd:Q1426 wdt:P106 ?profession .
   # get the label
   # ?profession sc:name ?name.
}
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('profession', 'http://www.wikidata.org/entity/Q10833314'), ('name', 'tennis player')]
# 1

# %% [markdown]
# ### Final query for this task

# %%
# write your final query

# TASK1: Identify the BGP for *tennis player* (wd:Q10833314)
# With this query I'm finding Roger Federer's (wd:Q1426) profession (wdt:P106), which is tennis player (wd:Q10833314).

queryString = """
# retrieving the BGP of the profession of Roger Federer
SELECT DISTINCT ?profession ?name
WHERE {
   # Roger Federer's (wd:Q1426) --profession (wdt:P106)--> ?profession
   wd:Q1426 wdt:P106 ?profession .
   # get the label of the ?profession
   # ?profession sc:name ?name.
}
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('profession', 'http://www.wikidata.org/entity/Q10833314'), ('name', 'tennis player')]
# 1

# %% [markdown]
# ## Task 2
# Identify the BGP for tennis tournament

# %%
# Identify the BGP for tennis tournament
# Roger Federer (wd:Q1426)
# tennis player (wd:Q10833314)

# trying to find any traces of a tennis tournament
queryString = """
SELECT DISTINCT ?p ?name
WHERE {
   # bind something
   wd:Q1426 ?p ?obj .
   # get the label
   # ?p sc:name ?name.
}
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P1006'), ('name', 'Nationale Thesaurus voor Auteurs ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P103'), ('name', 'native language')]
# [('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('p', 'http://www.wikidata.org/prop/direct/P108'), ('name', 'employer')]
# [('p', 'http://www.wikidata.org/prop/direct/P1263'), ('name', 'NNDB people ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1280'), ('name', 'CONOR.SI ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1284'), ('name', 'Munzinger person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1285'), ('name', 'Munzinger Sport number')]
# [('p', 'http://www.wikidata.org/prop/direct/P1296'), ('name', 'Gran Enciclopèdia Catalana ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1343'), ('name', 'described by source')]
# [('p', 'http://www.wikidata.org/prop/direct/P1344'), ('name', 'participant in')]
# [('p', 'http://www.wikidata.org/prop/direct/P1352'), ('name', 'ranking')]
# [('p', 'http://www.wikidata.org/prop/direct/P140'), ('name', 'religion')]
# [('p', 'http://www.wikidata.org/prop/direct/P1412'), ('name', 'languages spoken, written or signed')]
# [('p', 'http://www.wikidata.org/prop/direct/P1417'), ('name', 'Encyclopædia Britannica Online ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1447'), ('name', 'Sports-Reference.com Olympic athlete ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1532'), ('name', 'country for sport')]
# [('p', 'http://www.wikidata.org/prop/direct/P166'), ('name', 'award received')]
# [('p', 'http://www.wikidata.org/prop/direct/P1695'), ('name', 'NLP ID (unique)')]
# [('p', 'http://www.wikidata.org/prop/direct/P1741'), ('name', 'GTAA ID')]
# 20

# %%
# Identify the BGP for tennis tournament
# Roger Federer (wd:Q1426)
# tennis player (wd:Q10833314)

# trying to find any traces of a tennis tournament with ?obj & ?objName
queryString = """
SELECT DISTINCT ?p ?name ?obj ?objName
WHERE {
   # bind something
   wd:Q1426 ?p ?obj .
   # get the label
   # ?p sc:name ?name.
   # ?obj sc:name ?objName.
}
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P2522'), ('name', 'victory'), ('obj', 'http://www.wikidata.org/entity/Q22956224'), ('objName', "2017 Australian Open – Men's Singles")]
# [('p', 'http://www.wikidata.org/prop/direct/P2522'), ('name', 'victory'), ('obj', 'http://www.wikidata.org/entity/Q612597'), ('objName', '2007 Tennis Masters Cup')]
# [('p', 'http://www.wikidata.org/prop/direct/P3342'), ('name', 'significant person'), ('obj', 'http://www.wikidata.org/entity/Q54584'), ('objName', 'Andy Roddick')]
# [('p', 'http://www.wikidata.org/prop/direct/P166'), ('name', 'award received'), ('obj', 'http://www.wikidata.org/entity/Q56509472'), ('objName', 'honorary doctor of the University of Basel')]
# [('p', 'http://www.wikidata.org/prop/direct/P1344'), ('name', 'participant in'), ('obj', 'http://www.wikidata.org/entity/Q589310'), ('objName', "tennis at the 2000 Summer Olympics – men's singles")]
# [('p', 'http://www.wikidata.org/prop/direct/P6758'), ('name', 'supported sports team'), ('obj', 'http://www.wikidata.org/entity/Q189671'), ('objName', 'FC Basel')]
# [('p', 'http://www.wikidata.org/prop/direct/P2522'), ('name', 'victory'), ('obj', 'http://www.wikidata.org/entity/Q782589'), ('objName', "2010 Australian Open – Men's Singles")]
# [('p', 'http://www.wikidata.org/prop/direct/P2522'), ('name', 'victory'), ('obj', 'http://www.wikidata.org/entity/Q782420'), ('objName', "2006 Australian Open – Men's Singles")]
# [('p', 'http://www.wikidata.org/prop/direct/P166'), ('name', 'award received'), ('obj', 'http://www.wikidata.org/entity/Q1061233'), ('objName', "L'Équipe Champion of Champions")]
# [('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation'), ('obj', 'http://www.wikidata.org/entity/Q10833314'), ('objName', 'tennis player')]
# [('p', 'http://www.wikidata.org/prop/direct/P741'), ('name', 'playing hand'), ('obj', 'http://www.wikidata.org/entity/Q14420039'), ('objName', 'one-handed backhand')]
# [('p', 'http://www.wikidata.org/prop/direct/P1412'), ('name', 'languages spoken, written or signed'), ('obj', 'http://www.wikidata.org/entity/Q150'), ('objName', 'French')]
# [('p', 'http://www.wikidata.org/prop/direct/P1343'), ('name', 'described by source'), ('obj', 'http://www.wikidata.org/entity/Q17290934'), ('objName', 'Lentapedia')]
# [('p', 'http://www.wikidata.org/prop/direct/P1412'), ('name', 'languages spoken, written or signed'), ('obj', 'http://www.wikidata.org/entity/Q1860'), ('objName', 'English')]
# [('p', 'http://www.wikidata.org/prop/direct/P103'), ('name', 'native language'), ('obj', 'http://www.wikidata.org/entity/Q188'), ('objName', 'German')]
# [('p', 'http://www.wikidata.org/prop/direct/P1412'), ('name', 'languages spoken, written or signed'), ('obj', 'http://www.wikidata.org/entity/Q188'), ('objName', 'German')]
# [('p', 'http://www.wikidata.org/prop/direct/P39'), ('name', 'position held'), ('obj', 'http://www.wikidata.org/entity/Q19969187'), ('objName', 'UNICEF Goodwill Ambassador')]
# [('p', 'http://www.wikidata.org/prop/direct/P552'), ('name', 'handedness'), ('obj', 'http://www.wikidata.org/entity/Q3039938'), ('objName', 'right-handedness')]
# [('p', 'http://www.wikidata.org/prop/direct/P1532'), ('name', 'country for sport'), ('obj', 'http://www.wikidata.org/entity/Q39'), ('objName', 'Switzerland')]
# [('p', 'http://www.wikidata.org/prop/direct/P27'), ('name', 'country of citizenship'), ('obj', 'http://www.wikidata.org/entity/Q39'), ('objName', 'Switzerland')]
# 20

# %%
# Identify the BGP for tennis tournament
# Roger Federer (wd:Q1426)
# tennis player (wd:Q10833314)

# trying to find any traces of a tennis tournament with two degrees of depth
queryString = """
SELECT DISTINCT ?obj ?objName ?p ?name ?obj2 ?objName2
WHERE {
   # bind something
   wd:Q1426 wdt:P1344 ?obj .
   # ?obj ?p ?obj2.
   # get the label
   # ?p sc:name ?name.
   # ?obj sc:name ?objName.
   # ?obj2 sc:name ?objName2.
}
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('obj', 'http://www.wikidata.org/entity/Q8544'), ('objName', '2000 Summer Olympics'), ('p', 'http://www.wikidata.org/prop/direct/P115'), ('name', 'home venue'), ('obj2', 'http://www.wikidata.org/entity/Q295886'), ('objName2', 'Stadium Australia')]
# [('obj', 'http://www.wikidata.org/entity/Q8558'), ('objName', '2004 Summer Olympics'), ('p', 'http://www.wikidata.org/prop/direct/P1343'), ('name', 'described by source'), ('obj2', 'http://www.wikidata.org/entity/Q99413897'), ('objName2', 'Medvik')]
# [('obj', 'http://www.wikidata.org/entity/Q757054'), ('objName', "tennis at the 2008 Summer Olympics – men's doubles"), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('name', 'winner'), ('obj2', 'http://www.wikidata.org/entity/Q193661'), ('objName2', 'Stan Wawrinka')]
# [('obj', 'http://www.wikidata.org/entity/Q757054'), ('objName', "tennis at the 2008 Summer Olympics – men's doubles"), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('name', 'winner'), ('obj2', 'http://www.wikidata.org/entity/Q1426'), ('objName2', 'Roger Federer')]
# [('obj', 'http://www.wikidata.org/entity/Q581788'), ('objName', "tennis at the 2012 Summer Olympics – men's singles"), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('name', 'winner'), ('obj2', 'http://www.wikidata.org/entity/Q10125'), ('objName2', 'Andy Murray')]
# [('obj', 'http://www.wikidata.org/entity/Q589310'), ('objName', "tennis at the 2000 Summer Olympics – men's singles"), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('name', 'winner'), ('obj2', 'http://www.wikidata.org/entity/Q207705'), ('objName2', 'Yevgeny Kafelnikov')]
# [('obj', 'http://www.wikidata.org/entity/Q8544'), ('objName', '2000 Summer Olympics'), ('p', 'http://www.wikidata.org/prop/direct/P155'), ('name', 'follows'), ('obj2', 'http://www.wikidata.org/entity/Q8531'), ('objName2', '1996 Summer Olympics')]
# [('obj', 'http://www.wikidata.org/entity/Q8558'), ('objName', '2004 Summer Olympics'), ('p', 'http://www.wikidata.org/prop/direct/P155'), ('name', 'follows'), ('obj2', 'http://www.wikidata.org/entity/Q8544'), ('objName2', '2000 Summer Olympics')]
# [('obj', 'http://www.wikidata.org/entity/Q757054'), ('objName', "tennis at the 2008 Summer Olympics – men's doubles"), ('p', 'http://www.wikidata.org/prop/direct/P155'), ('name', 'follows'), ('obj2', 'http://www.wikidata.org/entity/Q938757'), ('objName2', "tennis at the 2004 Summer Olympics – men's doubles")]
# [('obj', 'http://www.wikidata.org/entity/Q581788'), ('objName', "tennis at the 2012 Summer Olympics – men's singles"), ('p', 'http://www.wikidata.org/prop/direct/P155'), ('name', 'follows'), ('obj2', 'http://www.wikidata.org/entity/Q752428'), ('objName2', "tennis at the 2008 Summer Olympics – men's singles")]
# [('obj', 'http://www.wikidata.org/entity/Q8544'), ('objName', '2000 Summer Olympics'), ('p', 'http://www.wikidata.org/prop/direct/P156'), ('name', 'followed by'), ('obj2', 'http://www.wikidata.org/entity/Q8558'), ('objName2', '2004 Summer Olympics')]
# [('obj', 'http://www.wikidata.org/entity/Q8558'), ('objName', '2004 Summer Olympics'), ('p', 'http://www.wikidata.org/prop/direct/P156'), ('name', 'followed by'), ('obj2', 'http://www.wikidata.org/entity/Q8567'), ('objName2', '2008 Summer Olympics')]
# [('obj', 'http://www.wikidata.org/entity/Q581788'), ('objName', "tennis at the 2012 Summer Olympics – men's singles"), ('p', 'http://www.wikidata.org/prop/direct/P156'), ('name', 'followed by'), ('obj2', 'http://www.wikidata.org/entity/Q23747965'), ('objName2', "tennis at the 2016 Summer Olympics – men's singles")]
# [('obj', 'http://www.wikidata.org/entity/Q757054'), ('objName', "tennis at the 2008 Summer Olympics – men's doubles"), ('p', 'http://www.wikidata.org/prop/direct/P156'), ('name', 'followed by'), ('obj2', 'http://www.wikidata.org/entity/Q374383'), ('objName2', "tennis at the 2012 Summer Olympics – men's doubles")]
# [('obj', 'http://www.wikidata.org/entity/Q581788'), ('objName', "tennis at the 2012 Summer Olympics – men's singles"), ('p', 'http://www.wikidata.org/prop/direct/P17'), ('name', 'country'), ('obj2', 'http://www.wikidata.org/entity/Q145'), ('objName2', 'United Kingdom')]
# [('obj', 'http://www.wikidata.org/entity/Q757054'), ('objName', "tennis at the 2008 Summer Olympics – men's doubles"), ('p', 'http://www.wikidata.org/prop/direct/P17'), ('name', 'country'), ('obj2', 'http://www.wikidata.org/entity/Q148'), ('objName2', "People's Republic of China")]
# [('obj', 'http://www.wikidata.org/entity/Q589310'), ('objName', "tennis at the 2000 Summer Olympics – men's singles"), ('p', 'http://www.wikidata.org/prop/direct/P17'), ('name', 'country'), ('obj2', 'http://www.wikidata.org/entity/Q408'), ('objName2', 'Australia')]
# [('obj', 'http://www.wikidata.org/entity/Q8544'), ('objName', '2000 Summer Olympics'), ('p', 'http://www.wikidata.org/prop/direct/P17'), ('name', 'country'), ('obj2', 'http://www.wikidata.org/entity/Q408'), ('objName2', 'Australia')]
# [('obj', 'http://www.wikidata.org/entity/Q8558'), ('objName', '2004 Summer Olympics'), ('p', 'http://www.wikidata.org/prop/direct/P17'), ('name', 'country'), ('obj2', 'http://www.wikidata.org/entity/Q41'), ('objName2', 'Greece')]
# [('obj', 'http://www.wikidata.org/entity/Q589310'), ('objName', "tennis at the 2000 Summer Olympics – men's singles"), ('p', 'http://www.wikidata.org/prop/direct/P2094'), ('name', 'competition class'), ('obj2', 'http://www.wikidata.org/entity/Q16893072'), ('objName2', "men's singles")]
# 20

# %%
# Identify the BGP for tennis tournament
# Roger Federer (wd:Q1426)
# tennis player (wd:Q10833314)
# winner (wdt:P1346)

# trying to find Roger Federer's achievements
queryString = """
SELECT DISTINCT ?obj ?objName 
WHERE {
   # bind something
   wd:Q1426 wdt:P1344 ?obj .
   # get the label
   # ?obj sc:name ?objName.
}
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('obj', 'http://www.wikidata.org/entity/Q589310'), ('objName', "tennis at the 2000 Summer Olympics – men's singles")]
# [('obj', 'http://www.wikidata.org/entity/Q8544'), ('objName', '2000 Summer Olympics')]
# [('obj', 'http://www.wikidata.org/entity/Q8558'), ('objName', '2004 Summer Olympics')]
# [('obj', 'http://www.wikidata.org/entity/Q581788'), ('objName', "tennis at the 2012 Summer Olympics – men's singles")]
# [('obj', 'http://www.wikidata.org/entity/Q757054'), ('objName', "tennis at the 2008 Summer Olympics – men's doubles")]
# 5

# %%
# Identify the BGP for tennis tournament
# Roger Federer (wd:Q1426)
# tennis player (wd:Q10833314)
# winner (wdt:P1346)
# "tennis at the 2000 Summer Olympics – men's singles" (wd:Q589310)

# trying to see where I can get from "tennis at the 2000 Summer Olympics – men's singles" (wd:Q589310)
queryString = """
SELECT DISTINCT ?p ?name
WHERE {
   # bind something
   wd:Q589310 ?p ?obj .
   # get the label
   # ?p sc:name ?name.
}
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P1132'), ('name', 'number of participants')]
# [('p', 'http://www.wikidata.org/prop/direct/P1346'), ('name', 'winner')]
# [('p', 'http://www.wikidata.org/prop/direct/P17'), ('name', 'country')]
# [('p', 'http://www.wikidata.org/prop/direct/P2094'), ('name', 'competition class')]
# [('p', 'http://www.wikidata.org/prop/direct/P2581'), ('name', 'BabelNet ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('name', 'instance of')]
# [('p', 'http://www.wikidata.org/prop/direct/P361'), ('name', 'part of')]
# [('p', 'http://www.wikidata.org/prop/direct/P585'), ('name', 'point in time')]
# [('p', 'http://www.wikidata.org/prop/direct/P641'), ('name', 'sport')]
# [('p', 'http://www.wikidata.org/prop/direct/P646'), ('name', 'Freebase ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P9055'), ('name', 'Olympedia event ID')]
# 11

# %%
# Identify the BGP for tennis tournament
# Roger Federer (wd:Q1426)
# tennis player (wd:Q10833314)
# winner (wdt:P1346)
# "tennis at the 2000 Summer Olympics – men's singles" (wd:Q589310)
# sport (wdt:P641)

# trying to see where I can get from "tennis at the 2000 Summer Olympics – men's singles" (wd:Q589310), with sport relation

queryString = """

SELECT DISTINCT ?obj ?objName 
WHERE {
   # bind something
   wd:Q589310 wdt:P641 ?obj .
   # get the label
   # ?obj sc:name ?objName.
}
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('obj', 'http://www.wikidata.org/entity/Q847'), ('objName', 'tennis')]
# 1

# %%
# Identify the BGP for tennis tournament
# Roger Federer (wd:Q1426)
# tennis player (wd:Q10833314)
# winner (wdt:P1346)
# "tennis at the 2000 Summer Olympics – men's singles" (wd:Q589310)
# sport (wdt:P641)
# part of (wdt:P361) 
# instance of (wdt:P31)

# trying to see where I can get from "tennis at the 2000 Summer Olympics – men's singles" (wd:Q589310), 
# with sport|part of|instance of relation

queryString = """
SELECT DISTINCT ?obj ?objName 
WHERE {
   # bind something
   wd:Q589310 wdt:P641|wdt:P361|wdt:P31 ?obj .
   # get the label
   # ?obj sc:name ?objName.
}
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('obj', 'http://www.wikidata.org/entity/Q18536594'), ('objName', 'Olympic sporting event')]
# [('obj', 'http://www.wikidata.org/entity/Q847'), ('objName', 'tennis')]
# [('obj', 'http://www.wikidata.org/entity/Q46190676'), ('objName', 'tennis event')]
# [('obj', 'http://www.wikidata.org/entity/Q661494'), ('objName', 'tennis at the 2000 Summer Olympics')]
# 4

# %%
# Identify the BGP for tennis tournament
# Roger Federer (wd:Q1426)
# tennis player (wd:Q10833314)
# winner (wdt:P1346)
# "tennis at the 2000 Summer Olympics – men's singles" (wd:Q589310)
# sport (wdt:P641)
# part of (wdt:P361) 
# instance of (wdt:P31)

# tennis event (wd:Q46190676)

# trying to see where I can get from "tennis event" (wd:Q46190676)

queryString = """
SELECT DISTINCT ?obj ?objName 
WHERE {
   # bind something
   wd:Q46190676 ?p ?obj .
   # get the label
   # ?obj sc:name ?objName.
}
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('obj', 'http://www.wikidata.org/entity/Q21170330'), ('objName', 'tennis qualification event')]
# [('obj', 'http://www.wikidata.org/entity/P361'), ('objName', 'part of')]
# [('obj', 'http://www.wikidata.org/entity/Q16510064'), ('objName', 'sporting event')]
# [('obj', 'http://www.wikidata.org/entity/Q847'), ('objName', 'tennis')]
# [('obj', 'http://www.wikidata.org/entity/P641'), ('objName', 'sport')]
# [('obj', 'http://www.wikidata.org/entity/Q47345468'), ('objName', 'tennis tournament edition')]
# [('obj', 'http://www.wikidata.org/entity/P1346'), ('objName', 'winner')]
# [('obj', 'http://www.wikidata.org/entity/P710'), ('objName', 'participant')]
# [('obj', 'http://www.wikidata.org/entity/P2094'), ('objName', 'competition class')]
# [('obj', 'http://www.wikidata.org/entity/Q47459169'), ('objName', 'tennis match')]
# [('obj', 'http://www.wikidata.org/entity/Q1967745'), ('objName', 'type of tennis match')]
# 11

# %%
# Identify the BGP for tennis tournament
# Roger Federer (wd:Q1426)
# tennis player (wd:Q10833314)
# winner (wdt:P1346)
# "tennis at the 2000 Summer Olympics – men's singles" (wd:Q589310)
# sport (wdt:P641)
# part of (wdt:P361) 
# instance of (wdt:P31)

# tennis event (wd:Q46190676)

# trying to see where I can get from "tennis event" (wd:Q46190676), check also property

queryString = """
SELECT DISTINCT ?p ?pName ?obj ?objName 
WHERE {
   # bind something
   wd:Q46190676 ?p ?obj .
   # get the label
   # ?obj sc:name ?objName.
   # ?p sc:name ?pName.
}
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P1552'), ('pName', 'has quality'), ('obj', 'http://www.wikidata.org/entity/Q1967745'), ('objName', 'type of tennis match')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('obj', 'http://www.wikidata.org/entity/P710'), ('objName', 'participant')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('obj', 'http://www.wikidata.org/entity/P641'), ('objName', 'sport')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('obj', 'http://www.wikidata.org/entity/P361'), ('objName', 'part of')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('obj', 'http://www.wikidata.org/entity/P2094'), ('objName', 'competition class')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('obj', 'http://www.wikidata.org/entity/P1346'), ('objName', 'winner')]
# [('p', 'http://www.wikidata.org/prop/direct/P2670'), ('pName', 'has parts of the class'), ('obj', 'http://www.wikidata.org/entity/Q47459169'), ('objName', 'tennis match')]
# [('p', 'http://www.wikidata.org/prop/direct/P2670'), ('pName', 'has parts of the class'), ('obj', 'http://www.wikidata.org/entity/Q21170330'), ('objName', 'tennis qualification event')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('obj', 'http://www.wikidata.org/entity/Q16510064'), ('objName', 'sporting event')]
# [('p', 'http://www.wikidata.org/prop/direct/P361'), ('pName', 'part of'), ('obj', 'http://www.wikidata.org/entity/Q47345468'), ('objName', 'tennis tournament edition')]
# [('p', 'http://www.wikidata.org/prop/direct/P641'), ('pName', 'sport'), ('obj', 'http://www.wikidata.org/entity/Q847'), ('objName', 'tennis')]
# 11

# %%
# Identify the BGP for tennis tournament
# Roger Federer (wd:Q1426)
# tennis player (wd:Q10833314)
# winner (wdt:P1346)
# "tennis at the 2000 Summer Olympics – men's singles" (wd:Q589310)
# sport (wdt:P641)
# part of (wdt:P361) 
# instance of (wdt:P31)
# tennis event (wd:Q46190676)

# wd:Q47459169 tennis match
# wd:Q21170330 tennis qualification event
# wd:Q16510064 sporting event
# wd:Q47345468 tennis tournament edition
# wd:Q847 tennis

# trying to see where I can get from "tennis match" (wd:Q47459169)

queryString = """
SELECT DISTINCT ?p ?pName ?obj ?objName 
WHERE {
   # bind something
   wd:Q47459169 ?p ?obj .
   # get the label
   # ?obj sc:name ?objName.
   # ?p sc:name ?pName.
}
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P2354'), ('pName', 'has list'), ('obj', 'http://www.wikidata.org/entity/Q7502163'), ('objName', 'Shortest tennis match records')]
# [('p', 'http://www.wikidata.org/prop/direct/P2670'), ('pName', 'has parts of the class'), ('obj', 'http://www.wikidata.org/entity/Q47537675'), ('objName', 'set')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('obj', 'http://www.wikidata.org/entity/Q13406554'), ('objName', 'sports competition')]
# [('p', 'http://www.wikidata.org/prop/direct/P641'), ('pName', 'sport'), ('obj', 'http://www.wikidata.org/entity/Q847'), ('objName', 'tennis')]
# [('p', 'http://www.wikidata.org/prop/direct/P910'), ('pName', "topic's main category"), ('obj', 'http://www.wikidata.org/entity/Q8843092'), ('objName', 'Category:Tennis matches')]
# 5

# %%
# Identify the BGP for tennis tournament
# Roger Federer (wd:Q1426)
# tennis player (wd:Q10833314)
# winner (wdt:P1346)
# "tennis at the 2000 Summer Olympics – men's singles" (wd:Q589310)
# sport (wdt:P641)
# part of (wdt:P361) 
# instance of (wdt:P31)
# tennis event (wd:Q46190676)

# wd:Q47459169 tennis match
# wd:Q21170330 tennis qualification event
# wd:Q16510064 sporting event
# wd:Q47345468 tennis tournament edition
# wd:Q847 tennis

# trying to see where I can get from "tennis qualification event" (wd:Q21170330), "sporting event" (wd:Q16510064) or "tennis" (wd:Q847)

queryString = """
SELECT DISTINCT ?p ?pName ?obj ?objName 
WHERE {
   # bind something
   # ?s ?p ?obj .
   # get the label
   # ?obj sc:name ?objName.
   # ?p sc:name ?pName.
   VALUES ?s { wd:Q21170330 wd:Q16510064 wd:Q847 }
}
LIMIT 20

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P1151'), ('pName', "topic's main Wikimedia portal"), ('obj', 'http://www.wikidata.org/entity/Q8288752'), ('objName', 'Portal:Tennis')]
# [('p', 'http://www.wikidata.org/prop/direct/P1269'), ('pName', 'facet of'), ('obj', 'http://www.wikidata.org/entity/Q349'), ('objName', 'sport')]
# [('p', 'http://www.wikidata.org/prop/direct/P1343'), ('pName', 'described by source'), ('obj', 'http://www.wikidata.org/entity/Q106727050'), ('objName', 'Metropolitan Museum of Art Tagging Vocabulary')]
# [('p', 'http://www.wikidata.org/prop/direct/P1424'), ('pName', "topic's main template"), ('obj', 'http://www.wikidata.org/entity/Q10943918'), ('objName', 'Template:Tennis box')]
# [('p', 'http://www.wikidata.org/prop/direct/P1424'), ('pName', "topic's main template"), ('obj', 'http://www.wikidata.org/entity/Q8087332'), ('objName', 'Template:Tennis-stub')]
# [('p', 'http://www.wikidata.org/prop/direct/P1424'), ('pName', "topic's main template"), ('obj', 'http://www.wikidata.org/entity/Q41300247'), ('objName', 'Template:Infobox sports match')]
# [('p', 'http://www.wikidata.org/prop/direct/P1889'), ('pName', 'different from'), ('obj', 'http://www.wikidata.org/entity/Q51031626'), ('objName', 'sport competition at a multi-sport event')]
# [('p', 'http://www.wikidata.org/prop/direct/P1889'), ('pName', 'different from'), ('obj', 'http://www.wikidata.org/entity/Q13406554'), ('objName', 'sports competition')]
# [('p', 'http://www.wikidata.org/prop/direct/P1889'), ('pName', 'different from'), ('obj', 'http://www.wikidata.org/entity/Q2312410'), ('objName', 'sports discipline')]
# [('p', 'http://www.wikidata.org/prop/direct/P1889'), ('pName', 'different from'), ('obj', 'http://www.wikidata.org/entity/Q12565374'), ('objName', 'Tenis')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('obj', 'http://www.wikidata.org/entity/P2501'), ('objName', 'results')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('obj', 'http://www.wikidata.org/entity/P276'), ('objName', 'location')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('obj', 'http://www.wikidata.org/entity/P585'), ('objName', 'point in time')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('obj', 'http://www.wikidata.org/entity/P2321'), ('objName', 'general classification of race participants')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('obj', 'http://www.wikidata.org/entity/P3494'), ('objName', 'points classification')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('obj', 'http://www.wikidata.org/entity/P3496'), ('objName', 'teams classification by points')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('obj', 'http://www.wikidata.org/entity/P3497'), ('objName', 'teams classification by time')]
# [('p', 'http://www.wikidata.org/prop/direct/P2184'), ('pName', 'history of topic'), ('obj', 'http://www.wikidata.org/entity/Q2295996'), ('objName', 'history of tennis')]
# [('p', 'http://www.wikidata.org/prop/direct/P2283'), ('pName', 'uses'), ('obj', 'http://www.wikidata.org/entity/Q153362'), ('objName', 'tennis racquet')]
# [('p', 'http://www.wikidata.org/prop/direct/P2283'), ('pName', 'uses'), ('obj', 'http://www.wikidata.org/entity/Q741118'), ('objName', 'tennis court')]
# 20

# %%
# Identify the BGP for tennis tournament
# Roger Federer (wd:Q1426)
# tennis player (wd:Q10833314)
# winner (wdt:P1346)
# "tennis at the 2000 Summer Olympics – men's singles" (wd:Q589310)
# sport (wdt:P641)
# part of (wdt:P361) 
# instance of (wdt:P31)
# tennis event (wd:Q46190676)

# wd:Q47459169 tennis match
# wd:Q21170330 tennis qualification event
# wd:Q16510064 sporting event
# wd:Q47345468 tennis tournament edition
# wd:Q847 tennis

# trying to see where I can get from "tennis qualification event" (wd:Q21170330), "sporting event" (wd:Q16510064) or "tennis" (wd:Q847)
# with the subject
queryString = """
SELECT DISTINCT ?s ?p ?pName ?obj ?objName 
WHERE {
   # bind something
   # ?s ?p ?obj .
   # get the label
   # ?obj sc:name ?objName.
   # ?p sc:name ?pName.
   VALUES ?s { wd:Q21170330 wd:Q16510064 wd:Q847 }
}
LIMIT 20

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('s', 'http://www.wikidata.org/entity/Q847'), ('p', 'http://www.wikidata.org/prop/direct/P1151'), ('pName', "topic's main Wikimedia portal"), ('obj', 'http://www.wikidata.org/entity/Q8288752'), ('objName', 'Portal:Tennis')]
# [('s', 'http://www.wikidata.org/entity/Q16510064'), ('p', 'http://www.wikidata.org/prop/direct/P1269'), ('pName', 'facet of'), ('obj', 'http://www.wikidata.org/entity/Q349'), ('objName', 'sport')]
# [('s', 'http://www.wikidata.org/entity/Q847'), ('p', 'http://www.wikidata.org/prop/direct/P1343'), ('pName', 'described by source'), ('obj', 'http://www.wikidata.org/entity/Q106727050'), ('objName', 'Metropolitan Museum of Art Tagging Vocabulary')]
# [('s', 'http://www.wikidata.org/entity/Q847'), ('p', 'http://www.wikidata.org/prop/direct/P1424'), ('pName', "topic's main template"), ('obj', 'http://www.wikidata.org/entity/Q10943918'), ('objName', 'Template:Tennis box')]
# [('s', 'http://www.wikidata.org/entity/Q847'), ('p', 'http://www.wikidata.org/prop/direct/P1424'), ('pName', "topic's main template"), ('obj', 'http://www.wikidata.org/entity/Q8087332'), ('objName', 'Template:Tennis-stub')]
# [('s', 'http://www.wikidata.org/entity/Q16510064'), ('p', 'http://www.wikidata.org/prop/direct/P1424'), ('pName', "topic's main template"), ('obj', 'http://www.wikidata.org/entity/Q41300247'), ('objName', 'Template:Infobox sports match')]
# [('s', 'http://www.wikidata.org/entity/Q16510064'), ('p', 'http://www.wikidata.org/prop/direct/P1889'), ('pName', 'different from'), ('obj', 'http://www.wikidata.org/entity/Q51031626'), ('objName', 'sport competition at a multi-sport event')]
# [('s', 'http://www.wikidata.org/entity/Q16510064'), ('p', 'http://www.wikidata.org/prop/direct/P1889'), ('pName', 'different from'), ('obj', 'http://www.wikidata.org/entity/Q13406554'), ('objName', 'sports competition')]
# [('s', 'http://www.wikidata.org/entity/Q16510064'), ('p', 'http://www.wikidata.org/prop/direct/P1889'), ('pName', 'different from'), ('obj', 'http://www.wikidata.org/entity/Q2312410'), ('objName', 'sports discipline')]
# [('s', 'http://www.wikidata.org/entity/Q847'), ('p', 'http://www.wikidata.org/prop/direct/P1889'), ('pName', 'different from'), ('obj', 'http://www.wikidata.org/entity/Q12565374'), ('objName', 'Tenis')]
# [('s', 'http://www.wikidata.org/entity/Q16510064'), ('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('obj', 'http://www.wikidata.org/entity/P2501'), ('objName', 'results')]
# [('s', 'http://www.wikidata.org/entity/Q16510064'), ('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('obj', 'http://www.wikidata.org/entity/P276'), ('objName', 'location')]
# [('s', 'http://www.wikidata.org/entity/Q16510064'), ('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('obj', 'http://www.wikidata.org/entity/P585'), ('objName', 'point in time')]
# [('s', 'http://www.wikidata.org/entity/Q16510064'), ('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('obj', 'http://www.wikidata.org/entity/P2321'), ('objName', 'general classification of race participants')]
# [('s', 'http://www.wikidata.org/entity/Q16510064'), ('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('obj', 'http://www.wikidata.org/entity/P3494'), ('objName', 'points classification')]
# [('s', 'http://www.wikidata.org/entity/Q16510064'), ('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('obj', 'http://www.wikidata.org/entity/P3496'), ('objName', 'teams classification by points')]
# [('s', 'http://www.wikidata.org/entity/Q16510064'), ('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('obj', 'http://www.wikidata.org/entity/P3497'), ('objName', 'teams classification by time')]
# [('s', 'http://www.wikidata.org/entity/Q847'), ('p', 'http://www.wikidata.org/prop/direct/P2184'), ('pName', 'history of topic'), ('obj', 'http://www.wikidata.org/entity/Q2295996'), ('objName', 'history of tennis')]
# [('s', 'http://www.wikidata.org/entity/Q847'), ('p', 'http://www.wikidata.org/prop/direct/P2283'), ('pName', 'uses'), ('obj', 'http://www.wikidata.org/entity/Q153362'), ('objName', 'tennis racquet')]
# [('s', 'http://www.wikidata.org/entity/Q847'), ('p', 'http://www.wikidata.org/prop/direct/P2283'), ('pName', 'uses'), ('obj', 'http://www.wikidata.org/entity/Q741118'), ('objName', 'tennis court')]
# 20

# %%
# Identify the BGP for tennis tournament
# Roger Federer (wd:Q1426)
# tennis player (wd:Q10833314)
# winner (wdt:P1346)
# "tennis at the 2000 Summer Olympics – men's singles" (wd:Q589310)
# sport (wdt:P641)
# part of (wdt:P361) 
# instance of (wdt:P31)
# tennis event (wd:Q46190676)

# wd:Q47459169 tennis match
# wd:Q21170330 tennis qualification event
# wd:Q16510064 sporting event
# wd:Q47345468 tennis tournament edition
# wd:Q847 tennis

# trying to see where I can get from "tennis" (wd:Q847)
# with the subject

queryString = """
SELECT DISTINCT ?p ?pName ?obj ?objName 
WHERE {
   # bind something
   # ?s ?p ?obj .
   # get the label
   # ?obj sc:name ?objName.
   # ?p sc:name ?pName.
   VALUES ?s { wd:Q847 }
}
LIMIT 20

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P1151'), ('pName', "topic's main Wikimedia portal"), ('obj', 'http://www.wikidata.org/entity/Q8288752'), ('objName', 'Portal:Tennis')]
# [('p', 'http://www.wikidata.org/prop/direct/P1343'), ('pName', 'described by source'), ('obj', 'http://www.wikidata.org/entity/Q106727050'), ('objName', 'Metropolitan Museum of Art Tagging Vocabulary')]
# [('p', 'http://www.wikidata.org/prop/direct/P1424'), ('pName', "topic's main template"), ('obj', 'http://www.wikidata.org/entity/Q8087332'), ('objName', 'Template:Tennis-stub')]
# [('p', 'http://www.wikidata.org/prop/direct/P1424'), ('pName', "topic's main template"), ('obj', 'http://www.wikidata.org/entity/Q10943918'), ('objName', 'Template:Tennis box')]
# [('p', 'http://www.wikidata.org/prop/direct/P1889'), ('pName', 'different from'), ('obj', 'http://www.wikidata.org/entity/Q12565374'), ('objName', 'Tenis')]
# [('p', 'http://www.wikidata.org/prop/direct/P2184'), ('pName', 'history of topic'), ('obj', 'http://www.wikidata.org/entity/Q2295996'), ('objName', 'history of tennis')]
# [('p', 'http://www.wikidata.org/prop/direct/P2283'), ('pName', 'uses'), ('obj', 'http://www.wikidata.org/entity/Q153362'), ('objName', 'tennis racquet')]
# [('p', 'http://www.wikidata.org/prop/direct/P2283'), ('pName', 'uses'), ('obj', 'http://www.wikidata.org/entity/Q741118'), ('objName', 'tennis court')]
# [('p', 'http://www.wikidata.org/prop/direct/P2283'), ('pName', 'uses'), ('obj', 'http://www.wikidata.org/entity/Q246514'), ('objName', 'tennis ball')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('obj', 'http://www.wikidata.org/entity/Q2426135'), ('objName', 'racket sport')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('obj', 'http://www.wikidata.org/entity/Q877517'), ('objName', 'ball game')]
# [('p', 'http://www.wikidata.org/prop/direct/P3095'), ('pName', 'practiced by'), ('obj', 'http://www.wikidata.org/entity/Q48676230'), ('objName', 'registered player')]
# [('p', 'http://www.wikidata.org/prop/direct/P3095'), ('pName', 'practiced by'), ('obj', 'http://www.wikidata.org/entity/Q10833314'), ('objName', 'tennis player')]
# [('p', 'http://www.wikidata.org/prop/direct/P3095'), ('pName', 'practiced by'), ('obj', 'http://www.wikidata.org/entity/Q48995125'), ('objName', 'amateur tennis player')]
# [('p', 'http://www.wikidata.org/prop/direct/P3095'), ('pName', 'practiced by'), ('obj', 'http://www.wikidata.org/entity/Q48673045'), ('objName', 'professional tennis player')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q31629'), ('objName', 'type of sport')]
# [('p', 'http://www.wikidata.org/prop/direct/P495'), ('pName', 'country of origin'), ('obj', 'http://www.wikidata.org/entity/Q21'), ('objName', 'England')]
# [('p', 'http://www.wikidata.org/prop/direct/P5008'), ('pName', 'on focus list of Wikimedia project'), ('obj', 'http://www.wikidata.org/entity/Q5460604'), ('objName', 'Wikipedia:Vital articles')]
# [('p', 'http://www.wikidata.org/prop/direct/P5125'), ('pName', 'Wikimedia outline'), ('obj', 'http://www.wikidata.org/entity/Q7112743'), ('objName', 'outline of tennis')]
# [('p', 'http://www.wikidata.org/prop/direct/P6104'), ('pName', 'maintained by WikiProject'), ('obj', 'http://www.wikidata.org/entity/Q5530169'), ('objName', 'WikiProject Tennis')]
# 20

# %%
# Identify the BGP for tennis tournament
# Roger Federer (wd:Q1426)
# tennis player (wd:Q10833314)
# winner (wdt:P1346)
# "tennis at the 2000 Summer Olympics – men's singles" (wd:Q589310)
# sport (wdt:P641)
# part of (wdt:P361) 
# instance of (wdt:P31)
# tennis event (wd:Q46190676)

# wd:Q47459169 tennis match
# wd:Q21170330 tennis qualification event
# wd:Q16510064 sporting event
# wd:Q47345468 tennis tournament edition
# wd:Q847 tennis

# trying to see where I can get from "tennis" (wd:Q847)
# with the subject, and extending LIMIT to 50

queryString = """
SELECT DISTINCT ?p ?pName ?obj ?objName 
WHERE {
   # bind something
   # ?s ?p ?obj .
   # get the label
   # ?obj sc:name ?objName.
   # ?p sc:name ?pName.
   VALUES ?s { wd:Q847 }
}
LIMIT 50

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P1151'), ('pName', "topic's main Wikimedia portal"), ('obj', 'http://www.wikidata.org/entity/Q8288752'), ('objName', 'Portal:Tennis')]
# [('p', 'http://www.wikidata.org/prop/direct/P1343'), ('pName', 'described by source'), ('obj', 'http://www.wikidata.org/entity/Q106727050'), ('objName', 'Metropolitan Museum of Art Tagging Vocabulary')]
# [('p', 'http://www.wikidata.org/prop/direct/P1424'), ('pName', "topic's main template"), ('obj', 'http://www.wikidata.org/entity/Q8087332'), ('objName', 'Template:Tennis-stub')]
# [('p', 'http://www.wikidata.org/prop/direct/P1424'), ('pName', "topic's main template"), ('obj', 'http://www.wikidata.org/entity/Q10943918'), ('objName', 'Template:Tennis box')]
# [('p', 'http://www.wikidata.org/prop/direct/P1889'), ('pName', 'different from'), ('obj', 'http://www.wikidata.org/entity/Q12565374'), ('objName', 'Tenis')]
# [('p', 'http://www.wikidata.org/prop/direct/P2184'), ('pName', 'history of topic'), ('obj', 'http://www.wikidata.org/entity/Q2295996'), ('objName', 'history of tennis')]
# [('p', 'http://www.wikidata.org/prop/direct/P2283'), ('pName', 'uses'), ('obj', 'http://www.wikidata.org/entity/Q153362'), ('objName', 'tennis racquet')]
# [('p', 'http://www.wikidata.org/prop/direct/P2283'), ('pName', 'uses'), ('obj', 'http://www.wikidata.org/entity/Q741118'), ('objName', 'tennis court')]
# [('p', 'http://www.wikidata.org/prop/direct/P2283'), ('pName', 'uses'), ('obj', 'http://www.wikidata.org/entity/Q246514'), ('objName', 'tennis ball')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('obj', 'http://www.wikidata.org/entity/Q2426135'), ('objName', 'racket sport')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('obj', 'http://www.wikidata.org/entity/Q877517'), ('objName', 'ball game')]
# [('p', 'http://www.wikidata.org/prop/direct/P3095'), ('pName', 'practiced by'), ('obj', 'http://www.wikidata.org/entity/Q48676230'), ('objName', 'registered player')]
# [('p', 'http://www.wikidata.org/prop/direct/P3095'), ('pName', 'practiced by'), ('obj', 'http://www.wikidata.org/entity/Q10833314'), ('objName', 'tennis player')]
# [('p', 'http://www.wikidata.org/prop/direct/P3095'), ('pName', 'practiced by'), ('obj', 'http://www.wikidata.org/entity/Q48995125'), ('objName', 'amateur tennis player')]
# [('p', 'http://www.wikidata.org/prop/direct/P3095'), ('pName', 'practiced by'), ('obj', 'http://www.wikidata.org/entity/Q48673045'), ('objName', 'professional tennis player')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q31629'), ('objName', 'type of sport')]
# [('p', 'http://www.wikidata.org/prop/direct/P495'), ('pName', 'country of origin'), ('obj', 'http://www.wikidata.org/entity/Q21'), ('objName', 'England')]
# [('p', 'http://www.wikidata.org/prop/direct/P5008'), ('pName', 'on focus list of Wikimedia project'), ('obj', 'http://www.wikidata.org/entity/Q5460604'), ('objName', 'Wikipedia:Vital articles')]
# [('p', 'http://www.wikidata.org/prop/direct/P5125'), ('pName', 'Wikimedia outline'), ('obj', 'http://www.wikidata.org/entity/Q7112743'), ('objName', 'outline of tennis')]
# [('p', 'http://www.wikidata.org/prop/direct/P6104'), ('pName', 'maintained by WikiProject'), ('obj', 'http://www.wikidata.org/entity/Q5530169'), ('objName', 'WikiProject Tennis')]
# [('p', 'http://www.wikidata.org/prop/direct/P797'), ('pName', 'authority'), ('obj', 'http://www.wikidata.org/entity/Q223041'), ('objName', 'International Tennis Federation')]
# [('p', 'http://www.wikidata.org/prop/direct/P910'), ('pName', "topic's main category"), ('obj', 'http://www.wikidata.org/entity/Q5325416'), ('objName', 'Category:Tennis')]
# 22

# %%
# Identify the BGP for tennis tournament
# Roger Federer (wd:Q1426)
# tennis player (wd:Q10833314)
# winner (wdt:P1346)
# "tennis at the 2000 Summer Olympics – men's singles" (wd:Q589310)
# sport (wdt:P641)
# part of (wdt:P361) 
# instance of (wdt:P31)
# tennis event (wd:Q46190676)

# wd:Q47459169 tennis match
# wd:Q21170330 tennis qualification event
# wd:Q16510064 sporting event
# wd:Q47345468 tennis tournament edition
# wd:Q847 tennis
# wd:Q223041 International Tennis Federation

# trying to see where I can get from "International Tennis Federation" (wd:Q223041)
queryString = """
SELECT DISTINCT ?p ?pName ?obj ?objName 
WHERE {
   # bind something
   # ?s ?p ?obj .
   # get the label
   # ?obj sc:name ?objName.
   # ?p sc:name ?pName.
   VALUES ?s { wd:Q223041 }
}
LIMIT 50

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P1424'), ('pName', "topic's main template"), ('obj', 'http://www.wikidata.org/entity/Q13233631'), ('objName', 'Template:ITF profile')]
# [('p', 'http://www.wikidata.org/prop/direct/P159'), ('pName', 'headquarters location'), ('obj', 'http://www.wikidata.org/entity/Q84'), ('objName', 'London')]
# [('p', 'http://www.wikidata.org/prop/direct/P1687'), ('pName', 'Wikidata property'), ('obj', 'http://www.wikidata.org/entity/P599'), ('objName', 'ITF player ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1687'), ('pName', 'Wikidata property'), ('obj', 'http://www.wikidata.org/entity/P4299'), ('objName', 'ITF wheelchair player ID until 2019')]
# [('p', 'http://www.wikidata.org/prop/direct/P1687'), ('pName', 'Wikidata property'), ('obj', 'http://www.wikidata.org/entity/P6841'), ('objName', 'ITF tournament ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1687'), ('pName', 'Wikidata property'), ('obj', 'http://www.wikidata.org/entity/P8618'), ('objName', 'ITF player ID 2020')]
# [('p', 'http://www.wikidata.org/prop/direct/P1830'), ('pName', 'owner of'), ('obj', 'http://www.wikidata.org/entity/Q14580049'), ('objName', 'ITF website')]
# [('p', 'http://www.wikidata.org/prop/direct/P1830'), ('pName', 'owner of'), ('obj', 'http://www.wikidata.org/entity/Q56617835'), ('objName', 'FedCup website')]
# [('p', 'http://www.wikidata.org/prop/direct/P2541'), ('pName', 'operating area'), ('obj', 'http://www.wikidata.org/entity/Q2'), ('objName', 'Earth')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q98426739'), ('objName', 'tennis association')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q11422536'), ('objName', 'international sport governing body')]
# [('p', 'http://www.wikidata.org/prop/direct/P463'), ('pName', 'member of'), ('obj', 'http://www.wikidata.org/entity/Q1067053'), ('objName', 'Global Association of International Sports Federations')]
# [('p', 'http://www.wikidata.org/prop/direct/P463'), ('pName', 'member of'), ('obj', 'http://www.wikidata.org/entity/Q2420112'), ('objName', 'Association of Summer Olympic International Federations')]
# [('p', 'http://www.wikidata.org/prop/direct/P6365'), ('pName', 'member category'), ('obj', 'http://www.wikidata.org/entity/Q8666190'), ('objName', 'Category:National members of the International Tennis Federation')]
# [('p', 'http://www.wikidata.org/prop/direct/P641'), ('pName', 'sport'), ('obj', 'http://www.wikidata.org/entity/Q847'), ('objName', 'tennis')]
# [('p', 'http://www.wikidata.org/prop/direct/P910'), ('pName', "topic's main category"), ('obj', 'http://www.wikidata.org/entity/Q8550725'), ('objName', 'Category:International Tennis Federation')]
# 16

# %%
# Identify the BGP for tennis tournament
# Roger Federer (wd:Q1426)
# tennis player (wd:Q10833314)
# winner (wdt:P1346)
# "tennis at the 2000 Summer Olympics – men's singles" (wd:Q589310)
# sport (wdt:P641)
# part of (wdt:P361) 
# instance of (wdt:P31)
# tennis event (wd:Q46190676)

# wd:Q47459169 tennis match
# wd:Q21170330 tennis qualification event
# wd:Q16510064 sporting event
# wd:Q47345468 tennis tournament edition
# wd:Q847 tennis
# wd:Q223041 International Tennis Federation

# trying to see where I can get from "tennis tournament edition" (wd:Q47345468)
queryString = """
SELECT DISTINCT ?p ?pName ?obj ?objName 
WHERE {
   # bind something
   # ?s ?p ?obj .
   # get the label
   # ?obj sc:name ?objName.
   # ?p sc:name ?pName.
   VALUES ?s { wd:Q47345468 }
}
LIMIT 50

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('obj', 'http://www.wikidata.org/entity/P527'), ('objName', 'has part')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('obj', 'http://www.wikidata.org/entity/P276'), ('objName', 'location')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('obj', 'http://www.wikidata.org/entity/P582'), ('objName', 'end time')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('obj', 'http://www.wikidata.org/entity/P641'), ('objName', 'sport')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('obj', 'http://www.wikidata.org/entity/P393'), ('objName', 'edition number')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('obj', 'http://www.wikidata.org/entity/P580'), ('objName', 'start time')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('obj', 'http://www.wikidata.org/entity/P585'), ('objName', 'point in time')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('obj', 'http://www.wikidata.org/entity/P17'), ('objName', 'country')]
# [('p', 'http://www.wikidata.org/prop/direct/P2670'), ('pName', 'has parts of the class'), ('obj', 'http://www.wikidata.org/entity/Q46190676'), ('objName', 'tennis event')]
# [('p', 'http://www.wikidata.org/prop/direct/P2670'), ('pName', 'has parts of the class'), ('obj', 'http://www.wikidata.org/entity/Q47382471'), ('objName', 'day-by-day summary')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('obj', 'http://www.wikidata.org/entity/Q27968055'), ('objName', 'recurrent event edition')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('obj', 'http://www.wikidata.org/entity/Q27020041'), ('objName', 'sports season')]
# [('p', 'http://www.wikidata.org/prop/direct/P361'), ('pName', 'part of'), ('obj', 'http://www.wikidata.org/entity/Q47358534'), ('objName', 'tennis tour edition')]
# [('p', 'http://www.wikidata.org/prop/direct/P361'), ('pName', 'part of'), ('obj', 'http://www.wikidata.org/entity/Q13219666'), ('objName', 'tennis tournament')]
# [('p', 'http://www.wikidata.org/prop/direct/P641'), ('pName', 'sport'), ('obj', 'http://www.wikidata.org/entity/Q847'), ('objName', 'tennis')]
# 15

# %%
# Identify the BGP for tennis tournament
# Roger Federer (wd:Q1426)
# tennis player (wd:Q10833314)
# winner (wdt:P1346)
# "tennis at the 2000 Summer Olympics – men's singles" (wd:Q589310)
# sport (wdt:P641)
# instance of (wdt:P31)
# tennis event (wd:Q46190676)

# wd:Q47459169 tennis match
# wd:Q21170330 tennis qualification event
# wd:Q16510064 sporting event
# wd:Q47345468 tennis tournament edition
# wd:Q847 tennis
# wd:Q223041 International Tennis Federation
# part of (wdt:P361) 

# Found tennis tournament from "tennis tournament edition" (wd:Q47345468) with relation "part of" (wdt:P361)

queryString = """
SELECT DISTINCT ?obj ?objName 
WHERE {
   # bind something
   wd:Q47345468 wdt:P361 ?obj .
   # get the label
   # ?obj sc:name ?objName.
}
LIMIT 50

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('obj', 'http://www.wikidata.org/entity/Q13219666'), ('objName', 'tennis tournament')]
# [('obj', 'http://www.wikidata.org/entity/Q47358534'), ('objName', 'tennis tour edition')]
# 2

# %% [markdown]
# ### Final query for this task

# %%
# write your final query
# Identify the BGP for tennis tournament
# Roger Federer (wd:Q1426)
# tennis player (wd:Q10833314)
# winner (wdt:P1346)
# "tennis at the 2000 Summer Olympics – men's singles" (wd:Q589310)
# sport (wdt:P641)
# instance of (wdt:P31)
# tennis event (wd:Q46190676)

# wd:Q47459169 tennis match
# wd:Q21170330 tennis qualification event
# wd:Q16510064 sporting event
# wd:Q47345468 tennis tournament edition
# wd:Q847 tennis
# wd:Q223041 International Tennis Federation
# part of (wdt:P361) 

# Found tennis tournament from "tennis tournament edition" (wd:Q47345468) with relation "part of" (wdt:P361)

# 'tennis tournament edition' (wd:Q47345468) is 'part of' (wdt:P361) 'tennis tournament' (wd:Q13219666)

queryString = """
SELECT DISTINCT ?obj ?objName 
WHERE {
   # bind something
   # 'tennis tournament edition' (wd:Q47345468) is 'part of' (wdt:P361) ?obj
   wd:Q47345468 wdt:P361 ?obj .
   # get the label
   # ?obj sc:name ?objName.
}
LIMIT 50
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('obj', 'http://www.wikidata.org/entity/Q13219666'), ('objName', 'tennis tournament')]
# [('obj', 'http://www.wikidata.org/entity/Q47358534'), ('objName', 'tennis tour edition')]
# 2

# %% [markdown]
# ## Task 3
# Return the four Grand Slam of tennis (hint: One of these four is Wimbledon) (the result set must be a list of four couples Grand Slam IRI and label).

# %%
# Return the four Grand Slam of tennis (hint: One of these four is Wimbledon) 
#   (the result set must be a list of four couples Grand Slam IRI and label).

# Roger Federer (wd:Q1426)
# tennis player (wd:Q10833314)
# winner (wdt:P1346)
# "tennis at the 2000 Summer Olympics – men's singles" (wd:Q589310)
# sport (wdt:P641)
# instance of (wdt:P31)
# tennis event (wd:Q46190676)

# wd:Q47459169 tennis match
# wd:Q21170330 tennis qualification event
# wd:Q16510064 sporting event
# wd:Q47345468 tennis tournament edition
# wd:Q847 tennis
# wd:Q223041 International Tennis Federation
# part of (wdt:P361) 

# trying to see where I can get from "tennis qualification event" (wd:Q21170330)

queryString = """
SELECT DISTINCT ?obj ?objName 
WHERE {
   # bind something
   wd:Q21170330 ?p ?obj .
   # get the label
   # ?p sc:name ?pName.
   # ?obj sc:name ?objName.
}
LIMIT 50

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('obj', 'http://www.wikidata.org/entity/Q2122052'), ('objName', 'qualification')]
# [('obj', 'http://www.wikidata.org/entity/Q847'), ('objName', 'tennis')]
# [('obj', 'http://www.wikidata.org/entity/Q46190676'), ('objName', 'tennis event')]
# 3

# %%
# Return the four Grand Slam of tennis (hint: One of these four is Wimbledon) 
#   (the result set must be a list of four couples Grand Slam IRI and label).

# Roger Federer (wd:Q1426)
# tennis player (wd:Q10833314)
# winner (wdt:P1346)
# "tennis at the 2000 Summer Olympics – men's singles" (wd:Q589310)
# sport (wdt:P641)
# instance of (wdt:P31)
# tennis event (wd:Q46190676)

# wd:Q47459169 tennis match
# wd:Q21170330 tennis qualification event
# wd:Q16510064 sporting event
# wd:Q47345468 tennis tournament edition
# wd:Q847 tennis
# wd:Q223041 International Tennis Federation
# part of (wdt:P361) 

# trying to see where I can get from "tennis event" (wd:Q46190676)

queryString = """
SELECT DISTINCT ?p ?pName ?obj ?objName 
WHERE {
   # bind something
   wd:Q46190676 ?p ?obj .
   # get the label
   # ?p sc:name ?pName.
   # ?obj sc:name ?objName.
}
LIMIT 50

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P2670'), ('pName', 'has parts of the class'), ('obj', 'http://www.wikidata.org/entity/Q21170330'), ('objName', 'tennis qualification event')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('obj', 'http://www.wikidata.org/entity/P361'), ('objName', 'part of')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('obj', 'http://www.wikidata.org/entity/Q16510064'), ('objName', 'sporting event')]
# [('p', 'http://www.wikidata.org/prop/direct/P641'), ('pName', 'sport'), ('obj', 'http://www.wikidata.org/entity/Q847'), ('objName', 'tennis')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('obj', 'http://www.wikidata.org/entity/P641'), ('objName', 'sport')]
# [('p', 'http://www.wikidata.org/prop/direct/P361'), ('pName', 'part of'), ('obj', 'http://www.wikidata.org/entity/Q47345468'), ('objName', 'tennis tournament edition')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('obj', 'http://www.wikidata.org/entity/P1346'), ('objName', 'winner')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('obj', 'http://www.wikidata.org/entity/P710'), ('objName', 'participant')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('obj', 'http://www.wikidata.org/entity/P2094'), ('objName', 'competition class')]
# [('p', 'http://www.wikidata.org/prop/direct/P2670'), ('pName', 'has parts of the class'), ('obj', 'http://www.wikidata.org/entity/Q47459169'), ('objName', 'tennis match')]
# [('p', 'http://www.wikidata.org/prop/direct/P1552'), ('pName', 'has quality'), ('obj', 'http://www.wikidata.org/entity/Q1967745'), ('objName', 'type of tennis match')]
# 11

# %%
# Return the four Grand Slam of tennis (hint: One of these four is Wimbledon) 
#   (the result set must be a list of four couples Grand Slam IRI and label).

# Roger Federer (wd:Q1426)
# tennis player (wd:Q10833314)
# winner (wdt:P1346)
# "tennis at the 2000 Summer Olympics – men's singles" (wd:Q589310)
# sport (wdt:P641)
# instance of (wdt:P31)
# tennis event (wd:Q46190676)

# wd:Q47459169 tennis match
# wd:Q21170330 tennis qualification event
# wd:Q16510064 sporting event
# wd:Q47345468 tennis tournament edition
# wd:Q847 tennis
# wd:Q223041 International Tennis Federation
# part of (wdt:P361) 

# trying to see where I can get from "tennis tournament edition" (wd:Q47345468)

queryString = """
SELECT DISTINCT ?p ?pName ?obj ?objName 
WHERE {
   # bind something
   wd:Q47345468 ?p ?obj .
   # get the label
   # ?p sc:name ?pName.
   # ?obj sc:name ?objName.
}
LIMIT 50

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('obj', 'http://www.wikidata.org/entity/P393'), ('objName', 'edition number')]
# [('p', 'http://www.wikidata.org/prop/direct/P2670'), ('pName', 'has parts of the class'), ('obj', 'http://www.wikidata.org/entity/Q47382471'), ('objName', 'day-by-day summary')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('obj', 'http://www.wikidata.org/entity/P580'), ('objName', 'start time')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('obj', 'http://www.wikidata.org/entity/P582'), ('objName', 'end time')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('obj', 'http://www.wikidata.org/entity/P17'), ('objName', 'country')]
# [('p', 'http://www.wikidata.org/prop/direct/P361'), ('pName', 'part of'), ('obj', 'http://www.wikidata.org/entity/Q13219666'), ('objName', 'tennis tournament')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('obj', 'http://www.wikidata.org/entity/Q27020041'), ('objName', 'sports season')]
# [('p', 'http://www.wikidata.org/prop/direct/P641'), ('pName', 'sport'), ('obj', 'http://www.wikidata.org/entity/Q847'), ('objName', 'tennis')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('obj', 'http://www.wikidata.org/entity/P527'), ('objName', 'has part')]
# [('p', 'http://www.wikidata.org/prop/direct/P361'), ('pName', 'part of'), ('obj', 'http://www.wikidata.org/entity/Q47358534'), ('objName', 'tennis tour edition')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('obj', 'http://www.wikidata.org/entity/P641'), ('objName', 'sport')]
# [('p', 'http://www.wikidata.org/prop/direct/P2670'), ('pName', 'has parts of the class'), ('obj', 'http://www.wikidata.org/entity/Q46190676'), ('objName', 'tennis event')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('obj', 'http://www.wikidata.org/entity/P276'), ('objName', 'location')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('obj', 'http://www.wikidata.org/entity/P585'), ('objName', 'point in time')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('obj', 'http://www.wikidata.org/entity/Q27968055'), ('objName', 'recurrent event edition')]
# 15

# %%
# Return the four Grand Slam of tennis (hint: One of these four is Wimbledon) 
#   (the result set must be a list of four couples Grand Slam IRI and label).

# Roger Federer (wd:Q1426)
# tennis player (wd:Q10833314)
# winner (wdt:P1346)
# "tennis at the 2000 Summer Olympics – men's singles" (wd:Q589310)
# sport (wdt:P641)
# instance of (wdt:P31)
# tennis event (wd:Q46190676)
# wd:Q47459169 tennis match
# wd:Q21170330 tennis qualification event
# wd:Q16510064 sporting event
# wd:Q47345468 tennis tournament edition
# wd:Q847 tennis
# wd:Q223041 International Tennis Federation
# part of (wdt:P361) 

# wd:Q13219666 'tennis tournament'
# trying to see where I can get from "tennis tournament" (wd:Q13219666)


queryString = """
SELECT DISTINCT ?p ?pName ?obj ?objName 
WHERE {
   # bind something
   wd:Q13219666 ?p ?obj .
   # get the label
   # ?p sc:name ?pName.
   # ?obj sc:name ?objName.
}
LIMIT 50

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('obj', 'http://www.wikidata.org/entity/Q13406554'), ('objName', 'sports competition')]
# [('p', 'http://www.wikidata.org/prop/direct/P641'), ('pName', 'sport'), ('obj', 'http://www.wikidata.org/entity/Q847'), ('objName', 'tennis')]
# [('p', 'http://www.wikidata.org/prop/direct/P2670'), ('pName', 'has parts of the class'), ('obj', 'http://www.wikidata.org/entity/Q46190676'), ('objName', 'tennis event')]
# [('p', 'http://www.wikidata.org/prop/direct/P1424'), ('pName', "topic's main template"), ('obj', 'http://www.wikidata.org/entity/Q6452600'), ('objName', 'Template:ATP Tournament')]
# [('p', 'http://www.wikidata.org/prop/direct/P2354'), ('pName', 'has list'), ('obj', 'http://www.wikidata.org/entity/Q6642846'), ('objName', 'list of tennis tournaments')]
# [('p', 'http://www.wikidata.org/prop/direct/P1424'), ('pName', "topic's main template"), ('obj', 'http://www.wikidata.org/entity/Q7474005'), ('objName', 'Template:Infobox tennis tournament year')]
# [('p', 'http://www.wikidata.org/prop/direct/P1424'), ('pName', "topic's main template"), ('obj', 'http://www.wikidata.org/entity/Q22803873'), ('objName', 'Template:WTA tournament')]
# [('p', 'http://www.wikidata.org/prop/direct/P910'), ('pName', "topic's main category"), ('obj', 'http://www.wikidata.org/entity/Q5325422'), ('objName', 'Category:Tennis tournaments')]
# [('p', 'http://www.wikidata.org/prop/direct/P1424'), ('pName', "topic's main template"), ('obj', 'http://www.wikidata.org/entity/Q10810031'), ('objName', 'Template:Infobox ATP Challenger Tournament')]
# 9

# %%
# Return the four Grand Slam of tennis (hint: One of these four is Wimbledon) 
#   (the result set must be a list of four couples Grand Slam IRI and label).

# Roger Federer (wd:Q1426)
# tennis player (wd:Q10833314)
# winner (wdt:P1346)
# "tennis at the 2000 Summer Olympics – men's singles" (wd:Q589310)
# sport (wdt:P641)
# instance of (wdt:P31)
# tennis event (wd:Q46190676)
# wd:Q47459169 tennis match
# wd:Q21170330 tennis qualification event
# wd:Q16510064 sporting event
# wd:Q47345468 tennis tournament edition
# wd:Q847 tennis
# wd:Q223041 International Tennis Federation
# part of (wdt:P361) 

# wd:Q13219666 'tennis tournament'
# Can't find a way to get so lets re-trying to see where I can get from "Roger Federer" (wd:Q1426)

queryString = """
SELECT DISTINCT ?p ?pName ?obj ?objName 
WHERE {
   # bind something
   wd:Q1426 ?p ?obj .
   # get the label
   # ?p sc:name ?pName.
   # ?obj sc:name ?objName.
}
LIMIT 50

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P2522'), ('pName', 'victory'), ('obj', 'http://www.wikidata.org/entity/Q22956224'), ('objName', "2017 Australian Open – Men's Singles")]
# [('p', 'http://www.wikidata.org/prop/direct/P2522'), ('pName', 'victory'), ('obj', 'http://www.wikidata.org/entity/Q612597'), ('objName', '2007 Tennis Masters Cup')]
# [('p', 'http://www.wikidata.org/prop/direct/P3342'), ('pName', 'significant person'), ('obj', 'http://www.wikidata.org/entity/Q54584'), ('objName', 'Andy Roddick')]
# [('p', 'http://www.wikidata.org/prop/direct/P166'), ('pName', 'award received'), ('obj', 'http://www.wikidata.org/entity/Q56509472'), ('objName', 'honorary doctor of the University of Basel')]
# [('p', 'http://www.wikidata.org/prop/direct/P1344'), ('pName', 'participant in'), ('obj', 'http://www.wikidata.org/entity/Q589310'), ('objName', "tennis at the 2000 Summer Olympics – men's singles")]
# [('p', 'http://www.wikidata.org/prop/direct/P6758'), ('pName', 'supported sports team'), ('obj', 'http://www.wikidata.org/entity/Q189671'), ('objName', 'FC Basel')]
# [('p', 'http://www.wikidata.org/prop/direct/P2522'), ('pName', 'victory'), ('obj', 'http://www.wikidata.org/entity/Q782589'), ('objName', "2010 Australian Open – Men's Singles")]
# [('p', 'http://www.wikidata.org/prop/direct/P2522'), ('pName', 'victory'), ('obj', 'http://www.wikidata.org/entity/Q782420'), ('objName', "2006 Australian Open – Men's Singles")]
# [('p', 'http://www.wikidata.org/prop/direct/P166'), ('pName', 'award received'), ('obj', 'http://www.wikidata.org/entity/Q1061233'), ('objName', "L'Équipe Champion of Champions")]
# [('p', 'http://www.wikidata.org/prop/direct/P106'), ('pName', 'occupation'), ('obj', 'http://www.wikidata.org/entity/Q10833314'), ('objName', 'tennis player')]
# [('p', 'http://www.wikidata.org/prop/direct/P741'), ('pName', 'playing hand'), ('obj', 'http://www.wikidata.org/entity/Q14420039'), ('objName', 'one-handed backhand')]
# [('p', 'http://www.wikidata.org/prop/direct/P1412'), ('pName', 'languages spoken, written or signed'), ('obj', 'http://www.wikidata.org/entity/Q150'), ('objName', 'French')]
# [('p', 'http://www.wikidata.org/prop/direct/P1343'), ('pName', 'described by source'), ('obj', 'http://www.wikidata.org/entity/Q17290934'), ('objName', 'Lentapedia')]
# [('p', 'http://www.wikidata.org/prop/direct/P1412'), ('pName', 'languages spoken, written or signed'), ('obj', 'http://www.wikidata.org/entity/Q1860'), ('objName', 'English')]
# [('p', 'http://www.wikidata.org/prop/direct/P103'), ('pName', 'native language'), ('obj', 'http://www.wikidata.org/entity/Q188'), ('objName', 'German')]
# [('p', 'http://www.wikidata.org/prop/direct/P1412'), ('pName', 'languages spoken, written or signed'), ('obj', 'http://www.wikidata.org/entity/Q188'), ('objName', 'German')]
# [('p', 'http://www.wikidata.org/prop/direct/P39'), ('pName', 'position held'), ('obj', 'http://www.wikidata.org/entity/Q19969187'), ('objName', 'UNICEF Goodwill Ambassador')]
# [('p', 'http://www.wikidata.org/prop/direct/P552'), ('pName', 'handedness'), ('obj', 'http://www.wikidata.org/entity/Q3039938'), ('objName', 'right-handedness')]
# [('p', 'http://www.wikidata.org/prop/direct/P1532'), ('pName', 'country for sport'), ('obj', 'http://www.wikidata.org/entity/Q39'), ('objName', 'Switzerland')]
# [('p', 'http://www.wikidata.org/prop/direct/P27'), ('pName', 'country of citizenship'), ('obj', 'http://www.wikidata.org/entity/Q39'), ('objName', 'Switzerland')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q5'), ('objName', 'human')]
# [('p', 'http://www.wikidata.org/prop/direct/P21'), ('pName', 'sex or gender'), ('obj', 'http://www.wikidata.org/entity/Q6581097'), ('objName', 'male')]
# [('p', 'http://www.wikidata.org/prop/direct/P1343'), ('pName', 'described by source'), ('obj', 'http://www.wikidata.org/entity/Q67311526'), ('objName', 'Obalky knih.cz')]
# [('p', 'http://www.wikidata.org/prop/direct/P108'), ('pName', 'employer'), ('obj', 'http://www.wikidata.org/entity/Q740308'), ('objName', 'UNICEF')]
# [('p', 'http://www.wikidata.org/prop/direct/P19'), ('pName', 'place of birth'), ('obj', 'http://www.wikidata.org/entity/Q78'), ('objName', 'Basel')]
# [('p', 'http://www.wikidata.org/prop/direct/P641'), ('pName', 'sport'), ('obj', 'http://www.wikidata.org/entity/Q847'), ('objName', 'tennis')]
# [('p', 'http://www.wikidata.org/prop/direct/P1344'), ('pName', 'participant in'), ('obj', 'http://www.wikidata.org/entity/Q8544'), ('objName', '2000 Summer Olympics')]
# [('p', 'http://www.wikidata.org/prop/direct/P1344'), ('pName', 'participant in'), ('obj', 'http://www.wikidata.org/entity/Q8558'), ('objName', '2004 Summer Olympics')]
# [('p', 'http://www.wikidata.org/prop/direct/P140'), ('pName', 'religion'), ('obj', 'http://www.wikidata.org/entity/Q9592'), ('objName', 'Catholic Church')]
# [('p', 'http://www.wikidata.org/prop/direct/P2522'), ('pName', 'victory'), ('obj', 'http://www.wikidata.org/entity/Q300024'), ('objName', '2011 ATP World Tour Finals')]
# [('p', 'http://www.wikidata.org/prop/direct/P2416'), ('pName', 'sports discipline competed in'), ('obj', 'http://www.wikidata.org/entity/Q18123880'), ('objName', 'tennis singles')]
# [('p', 'http://www.wikidata.org/prop/direct/P2416'), ('pName', 'sports discipline competed in'), ('obj', 'http://www.wikidata.org/entity/Q18123885'), ('objName', 'tennis doubles')]
# [('p', 'http://www.wikidata.org/prop/direct/P735'), ('pName', 'given name'), ('obj', 'http://www.wikidata.org/entity/Q4925304'), ('objName', 'Roger')]
# [('p', 'http://www.wikidata.org/prop/direct/P166'), ('pName', 'award received'), ('obj', 'http://www.wikidata.org/entity/Q338737'), ('objName', 'Swiss Sports Personality of the Year')]
# [('p', 'http://www.wikidata.org/prop/direct/P166'), ('pName', 'award received'), ('obj', 'http://www.wikidata.org/entity/Q3494048'), ('objName', 'BBC Overseas Sports Personality of the Year')]
# [('p', 'http://www.wikidata.org/prop/direct/P1344'), ('pName', 'participant in'), ('obj', 'http://www.wikidata.org/entity/Q581788'), ('objName', "tennis at the 2012 Summer Olympics – men's singles")]
# [('p', 'http://www.wikidata.org/prop/direct/P2522'), ('pName', 'victory'), ('obj', 'http://www.wikidata.org/entity/Q753300'), ('objName', "2012 Wimbledon Championships – Gentlemen's Singles")]
# [('p', 'http://www.wikidata.org/prop/direct/P1344'), ('pName', 'participant in'), ('obj', 'http://www.wikidata.org/entity/Q757054'), ('objName', "tennis at the 2008 Summer Olympics – men's doubles")]
# [('p', 'http://www.wikidata.org/prop/direct/P2522'), ('pName', 'victory'), ('obj', 'http://www.wikidata.org/entity/Q757054'), ('objName', "tennis at the 2008 Summer Olympics – men's doubles")]
# [('p', 'http://www.wikidata.org/prop/direct/P2522'), ('pName', 'victory'), ('obj', 'http://www.wikidata.org/entity/Q1074654'), ('objName', "2006 Wimbledon Championships – Men's Singles")]
# [('p', 'http://www.wikidata.org/prop/direct/P2522'), ('pName', 'victory'), ('obj', 'http://www.wikidata.org/entity/Q384929'), ('objName', "2005 Wimbledon Championships – Men's Singles")]
# [('p', 'http://www.wikidata.org/prop/direct/P551'), ('pName', 'residence'), ('obj', 'http://www.wikidata.org/entity/Q70036'), ('objName', 'Bottmingen')]
# [('p', 'http://www.wikidata.org/prop/direct/P2522'), ('pName', 'victory'), ('obj', 'http://www.wikidata.org/entity/Q14916861'), ('objName', '2014 Davis Cup')]
# [('p', 'http://www.wikidata.org/prop/direct/P741'), ('pName', 'playing hand'), ('obj', 'http://www.wikidata.org/entity/Q14419931'), ('objName', 'one-handed forehand')]
# [('p', 'http://www.wikidata.org/prop/direct/P2522'), ('pName', 'victory'), ('obj', 'http://www.wikidata.org/entity/Q46993124'), ('objName', "2018 Australian Open – Men's Singles")]
# [('p', 'http://www.wikidata.org/prop/direct/P166'), ('pName', 'award received'), ('obj', 'http://www.wikidata.org/entity/Q4896696'), ('objName', 'Best International Athlete ESPY Award')]
# [('p', 'http://www.wikidata.org/prop/direct/P286'), ('pName', 'head coach'), ('obj', 'http://www.wikidata.org/entity/Q15649219'), ('objName', 'Severin Lüthi')]
# [('p', 'http://www.wikidata.org/prop/direct/P734'), ('pName', 'family name'), ('obj', 'http://www.wikidata.org/entity/Q16869916'), ('objName', 'Federer')]
# [('p', 'http://www.wikidata.org/prop/direct/P286'), ('pName', 'head coach'), ('obj', 'http://www.wikidata.org/entity/Q261095'), ('objName', 'Ivan Ljubičić')]
# [('p', 'http://www.wikidata.org/prop/direct/P2522'), ('pName', 'victory'), ('obj', 'http://www.wikidata.org/entity/Q964291'), ('objName', '2006 Tennis Masters Cup')]
# 50

# %%
# Return the four Grand Slam of tennis (hint: One of these four is Wimbledon) 
#   (the result set must be a list of four couples Grand Slam IRI and label).

# Roger Federer (wd:Q1426)
# tennis player (wd:Q10833314)
# winner (wdt:P1346)
# "tennis at the 2000 Summer Olympics – men's singles" (wd:Q589310)
# sport (wdt:P641)
# instance of (wdt:P31)
# tennis event (wd:Q46190676)
# wd:Q47459169 tennis match
# wd:Q21170330 tennis qualification event
# wd:Q16510064 sporting event
# wd:Q47345468 tennis tournament edition
# wd:Q847 tennis
# wd:Q223041 International Tennis Federation
# part of (wdt:P361) 
# wd:Q13219666 'tennis tournament'

# wdt:P2522 'victory' 
# wd:Q782589 "2010 Australian Open – Men's Singles"

# Can't find a way to get so lets re-trying to see where I can get from "Roger Federer" (wd:Q1426), 
# his achievements with two degrees of depth

queryString = """
SELECT DISTINCT ?objName ?p ?pName ?obj2 ?objName2
WHERE {
   # bind something
   wd:Q1426 wdt:P2522 ?obj .
   # ?obj sc:name ?objName.
   
   # ?obj ?p ?obj2.
   # ?p sc:name ?pName .
   # ?obj2 sc:name ?objName2 .
}
LIMIT 50

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('objName', "tennis at the 2008 Summer Olympics – men's doubles"), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner'), ('obj2', 'http://www.wikidata.org/entity/Q193661'), ('objName2', 'Stan Wawrinka')]
# [('objName', '2014 Davis Cup'), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner'), ('obj2', 'http://www.wikidata.org/entity/Q674139'), ('objName2', 'Switzerland Davis Cup team')]
# [('objName', "2017 Australian Open – Men's Singles"), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner'), ('obj2', 'http://www.wikidata.org/entity/Q1426'), ('objName2', 'Roger Federer')]
# [('objName', "2010 Australian Open – Men's Singles"), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner'), ('obj2', 'http://www.wikidata.org/entity/Q1426'), ('objName2', 'Roger Federer')]
# [('objName', "2006 Australian Open – Men's Singles"), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner'), ('obj2', 'http://www.wikidata.org/entity/Q1426'), ('objName2', 'Roger Federer')]
# [('objName', "2012 Wimbledon Championships – Gentlemen's Singles"), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner'), ('obj2', 'http://www.wikidata.org/entity/Q1426'), ('objName2', 'Roger Federer')]
# [('objName', "tennis at the 2008 Summer Olympics – men's doubles"), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner'), ('obj2', 'http://www.wikidata.org/entity/Q1426'), ('objName2', 'Roger Federer')]
# [('objName', "2006 Wimbledon Championships – Men's Singles"), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner'), ('obj2', 'http://www.wikidata.org/entity/Q1426'), ('objName2', 'Roger Federer')]
# [('objName', "2005 Wimbledon Championships – Men's Singles"), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner'), ('obj2', 'http://www.wikidata.org/entity/Q1426'), ('objName2', 'Roger Federer')]
# [('objName', "2018 Australian Open – Men's Singles"), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner'), ('obj2', 'http://www.wikidata.org/entity/Q1426'), ('objName2', 'Roger Federer')]
# [('objName', "2004 US Open – Men's Singles"), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner'), ('obj2', 'http://www.wikidata.org/entity/Q1426'), ('objName2', 'Roger Federer')]
# [('objName', "2005 US Open – Men's Singles"), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner'), ('obj2', 'http://www.wikidata.org/entity/Q1426'), ('objName2', 'Roger Federer')]
# [('objName', "2009 French Open – Men's Singles"), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner'), ('obj2', 'http://www.wikidata.org/entity/Q1426'), ('objName2', 'Roger Federer')]
# [('objName', "2006 US Open – Men's Singles"), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner'), ('obj2', 'http://www.wikidata.org/entity/Q1426'), ('objName2', 'Roger Federer')]
# [('objName', "2004 Wimbledon Championships – Men's Singles"), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner'), ('obj2', 'http://www.wikidata.org/entity/Q1426'), ('objName2', 'Roger Federer')]
# [('objName', "2003 Wimbledon Championships – Men's Singles"), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner'), ('obj2', 'http://www.wikidata.org/entity/Q1426'), ('objName2', 'Roger Federer')]
# [('objName', "2004 Australian Open - men's singles"), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner'), ('obj2', 'http://www.wikidata.org/entity/Q1426'), ('objName2', 'Roger Federer')]
# [('objName', "2017 Wimbledon Championships – Men's Singles"), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner'), ('obj2', 'http://www.wikidata.org/entity/Q1426'), ('objName2', 'Roger Federer')]
# [('objName', '2011 BNP Paribas Masters – singles'), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner'), ('obj2', 'http://www.wikidata.org/entity/Q1426'), ('objName2', 'Roger Federer')]
# [('objName', "2009 Wimbledon Championships – Men's Singles"), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner'), ('obj2', 'http://www.wikidata.org/entity/Q1426'), ('objName2', 'Roger Federer')]
# [('objName', "2007 Australian Open – Men's Singles"), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner'), ('obj2', 'http://www.wikidata.org/entity/Q1426'), ('objName2', 'Roger Federer')]
# [('objName', "2007 Wimbledon Championships – Men's Singles"), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner'), ('obj2', 'http://www.wikidata.org/entity/Q1426'), ('objName2', 'Roger Federer')]
# [('objName', "2008 US Open – Men's Singles"), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner'), ('obj2', 'http://www.wikidata.org/entity/Q1426'), ('objName2', 'Roger Federer')]
# [('objName', "2007 US Open – Men's Singles"), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner'), ('obj2', 'http://www.wikidata.org/entity/Q1426'), ('objName2', 'Roger Federer')]
# [('objName', '2014 Davis Cup'), ('p', 'http://www.wikidata.org/prop/direct/P1424'), ('pName', "topic's main template"), ('obj2', 'http://www.wikidata.org/entity/Q19507830'), ('objName2', 'Template:2014 Davis Cup')]
# [('objName', "2018 Australian Open – Men's Singles"), ('p', 'http://www.wikidata.org/prop/direct/P155'), ('pName', 'follows'), ('obj2', 'http://www.wikidata.org/entity/Q22956224'), ('objName2', "2017 Australian Open – Men's Singles")]
# [('objName', "tennis at the 2008 Summer Olympics – men's doubles"), ('p', 'http://www.wikidata.org/prop/direct/P155'), ('pName', 'follows'), ('obj2', 'http://www.wikidata.org/entity/Q938757'), ('objName2', "tennis at the 2004 Summer Olympics – men's doubles")]
# [('objName', "2006 Wimbledon Championships – Men's Singles"), ('p', 'http://www.wikidata.org/prop/direct/P155'), ('pName', 'follows'), ('obj2', 'http://www.wikidata.org/entity/Q384929'), ('objName2', "2005 Wimbledon Championships – Men's Singles")]
# [('objName', "2004 US Open – Men's Singles"), ('p', 'http://www.wikidata.org/prop/direct/P155'), ('pName', 'follows'), ('obj2', 'http://www.wikidata.org/entity/Q965872'), ('objName2', "2003 US Open – Men's Singles")]
# [('objName', "2003 Wimbledon Championships – Men's Singles"), ('p', 'http://www.wikidata.org/prop/direct/P155'), ('pName', 'follows'), ('obj2', 'http://www.wikidata.org/entity/Q935611'), ('objName2', "2002 Wimbledon Championships – Men's Singles")]
# [('objName', "2005 US Open – Men's Singles"), ('p', 'http://www.wikidata.org/prop/direct/P155'), ('pName', 'follows'), ('obj2', 'http://www.wikidata.org/entity/Q1048953'), ('objName2', "2004 US Open – Men's Singles")]
# [('objName', "2006 US Open – Men's Singles"), ('p', 'http://www.wikidata.org/prop/direct/P155'), ('pName', 'follows'), ('obj2', 'http://www.wikidata.org/entity/Q731509'), ('objName2', "2005 US Open – Men's Singles")]
# [('objName', "2007 US Open – Men's Singles"), ('p', 'http://www.wikidata.org/prop/direct/P155'), ('pName', 'follows'), ('obj2', 'http://www.wikidata.org/entity/Q912506'), ('objName2', "2006 US Open – Men's Singles")]
# [('objName', "2005 Wimbledon Championships – Men's Singles"), ('p', 'http://www.wikidata.org/prop/direct/P155'), ('pName', 'follows'), ('obj2', 'http://www.wikidata.org/entity/Q248965'), ('objName2', "2004 Wimbledon Championships – Men's Singles")]
# [('objName', "2004 Wimbledon Championships – Men's Singles"), ('p', 'http://www.wikidata.org/prop/direct/P155'), ('pName', 'follows'), ('obj2', 'http://www.wikidata.org/entity/Q378627'), ('objName2', "2003 Wimbledon Championships – Men's Singles")]
# [('objName', "2017 Wimbledon Championships – Men's Singles"), ('p', 'http://www.wikidata.org/prop/direct/P155'), ('pName', 'follows'), ('obj2', 'http://www.wikidata.org/entity/Q24487405'), ('objName2', "2016 Wimbledon Championships – Men's Singles")]
# [('objName', "2008 US Open – Men's Singles"), ('p', 'http://www.wikidata.org/prop/direct/P155'), ('pName', 'follows'), ('obj2', 'http://www.wikidata.org/entity/Q836815'), ('objName2', "2007 US Open – Men's Singles")]
# [('objName', "tennis at the 2008 Summer Olympics – men's doubles"), ('p', 'http://www.wikidata.org/prop/direct/P156'), ('pName', 'followed by'), ('obj2', 'http://www.wikidata.org/entity/Q374383'), ('objName2', "tennis at the 2012 Summer Olympics – men's doubles")]
# [('objName', "2005 Wimbledon Championships – Men's Singles"), ('p', 'http://www.wikidata.org/prop/direct/P156'), ('pName', 'followed by'), ('obj2', 'http://www.wikidata.org/entity/Q1074654'), ('objName2', "2006 Wimbledon Championships – Men's Singles")]
# [('objName', "2004 Wimbledon Championships – Men's Singles"), ('p', 'http://www.wikidata.org/prop/direct/P156'), ('pName', 'followed by'), ('obj2', 'http://www.wikidata.org/entity/Q384929'), ('objName2', "2005 Wimbledon Championships – Men's Singles")]
# [('objName', "2004 US Open – Men's Singles"), ('p', 'http://www.wikidata.org/prop/direct/P156'), ('pName', 'followed by'), ('obj2', 'http://www.wikidata.org/entity/Q731509'), ('objName2', "2005 US Open – Men's Singles")]
# [('objName', "2005 US Open – Men's Singles"), ('p', 'http://www.wikidata.org/prop/direct/P156'), ('pName', 'followed by'), ('obj2', 'http://www.wikidata.org/entity/Q912506'), ('objName2', "2006 US Open – Men's Singles")]
# [('objName', "2003 Wimbledon Championships – Men's Singles"), ('p', 'http://www.wikidata.org/prop/direct/P156'), ('pName', 'followed by'), ('obj2', 'http://www.wikidata.org/entity/Q248965'), ('objName2', "2004 Wimbledon Championships – Men's Singles")]
# [('objName', "2008 US Open – Men's Singles"), ('p', 'http://www.wikidata.org/prop/direct/P156'), ('pName', 'followed by'), ('obj2', 'http://www.wikidata.org/entity/Q838477'), ('objName2', "2009 US Open – Men's Singles")]
# [('objName', "2018 Australian Open – Men's Singles"), ('p', 'http://www.wikidata.org/prop/direct/P156'), ('pName', 'followed by'), ('obj2', 'http://www.wikidata.org/entity/Q48213295'), ('objName2', "2019 Australian Open – Men's Singles")]
# [('objName', "2007 US Open – Men's Singles"), ('p', 'http://www.wikidata.org/prop/direct/P156'), ('pName', 'followed by'), ('obj2', 'http://www.wikidata.org/entity/Q304072'), ('objName2', "2008 US Open – Men's Singles")]
# [('objName', "2006 US Open – Men's Singles"), ('p', 'http://www.wikidata.org/prop/direct/P156'), ('pName', 'followed by'), ('obj2', 'http://www.wikidata.org/entity/Q836815'), ('objName2', "2007 US Open – Men's Singles")]
# [('objName', "2017 Wimbledon Championships – Men's Singles"), ('p', 'http://www.wikidata.org/prop/direct/P156'), ('pName', 'followed by'), ('obj2', 'http://www.wikidata.org/entity/Q54961494'), ('objName2', "2018 Wimbledon Championships – Men's Singles")]
# [('objName', "2009 French Open – Men's Singles"), ('p', 'http://www.wikidata.org/prop/direct/P17'), ('pName', 'country'), ('obj2', 'http://www.wikidata.org/entity/Q142'), ('objName2', 'France')]
# [('objName', '2011 BNP Paribas Masters – singles'), ('p', 'http://www.wikidata.org/prop/direct/P17'), ('pName', 'country'), ('obj2', 'http://www.wikidata.org/entity/Q142'), ('objName2', 'France')]
# 50

# %%
# Return the four Grand Slam of tennis (hint: One of these four is Wimbledon) 
#   (the result set must be a list of four couples Grand Slam IRI and label).

# Roger Federer (wd:Q1426)
# tennis player (wd:Q10833314)
# winner (wdt:P1346)
# "tennis at the 2000 Summer Olympics – men's singles" (wd:Q589310)
# sport (wdt:P641)
# instance of (wdt:P31)
# tennis event (wd:Q46190676)
# wd:Q47459169 tennis match
# wd:Q21170330 tennis qualification event
# wd:Q16510064 sporting event
# wd:Q47345468 tennis tournament edition
# wd:Q847 tennis
# wd:Q223041 International Tennis Federation
# part of (wdt:P361) 
# wd:Q13219666 'tennis tournament'

# wdt:P2522 'victory' 
# wd:Q782589 "2010 Australian Open – Men's Singles"

# Can't find a way to get so lets re-trying to see where I can get from "Roger Federer" (wd:Q1426), 
# his achievements with two degrees of depth
# and excluding some relations

queryString = """
SELECT DISTINCT ?objName ?p ?pName ?obj2 ?objName2
WHERE {
   # bind something
   wd:Q1426 wdt:P2522 ?obj .
   # ?obj sc:name ?objName.
   
   # ?obj ?p ?obj2.
   # ?p sc:name ?pName .
   # ?obj2 sc:name ?objName2 .
   
   # != from winner, follows , followed by
   FILTER (?p != wdt:P1346 && ?p != wdt:P155 && ?p != wdt:P156)
}
LIMIT 50

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('objName', "2017 Australian Open – Men's Singles"), ('p', 'http://www.wikidata.org/prop/direct/P17'), ('pName', 'country'), ('obj2', 'http://www.wikidata.org/entity/Q408'), ('objName2', 'Australia')]
# [('objName', "2017 Australian Open – Men's Singles"), ('p', 'http://www.wikidata.org/prop/direct/P2094'), ('pName', 'competition class'), ('obj2', 'http://www.wikidata.org/entity/Q16893072'), ('objName2', "men's singles")]
# [('objName', "2017 Australian Open – Men's Singles"), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj2', 'http://www.wikidata.org/entity/Q46190676'), ('objName2', 'tennis event')]
# [('objName', "2017 Australian Open – Men's Singles"), ('p', 'http://www.wikidata.org/prop/direct/P361'), ('pName', 'part of'), ('obj2', 'http://www.wikidata.org/entity/Q22077628'), ('objName2', '2017 Australian Open')]
# [('objName', "2017 Australian Open – Men's Singles"), ('p', 'http://www.wikidata.org/prop/direct/P641'), ('pName', 'sport'), ('obj2', 'http://www.wikidata.org/entity/Q847'), ('objName2', 'tennis')]
# [('objName', '2007 Tennis Masters Cup'), ('p', 'http://www.wikidata.org/prop/direct/P17'), ('pName', 'country'), ('obj2', 'http://www.wikidata.org/entity/Q145'), ('objName2', 'United Kingdom')]
# [('objName', '2007 Tennis Masters Cup'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj2', 'http://www.wikidata.org/entity/Q270907'), ('objName2', 'ATP Finals')]
# [('objName', '2007 Tennis Masters Cup'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj2', 'http://www.wikidata.org/entity/Q47345468'), ('objName2', 'tennis tournament edition')]
# [('objName', '2007 Tennis Masters Cup'), ('p', 'http://www.wikidata.org/prop/direct/P3450'), ('pName', 'sports season of league or competition'), ('obj2', 'http://www.wikidata.org/entity/Q270907'), ('objName2', 'ATP Finals')]
# [('objName', '2007 Tennis Masters Cup'), ('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('obj2', 'http://www.wikidata.org/entity/Q3983549'), ('objName2', '2007 Tennis Masters Cup – singles')]
# [('objName', '2007 Tennis Masters Cup'), ('p', 'http://www.wikidata.org/prop/direct/P641'), ('pName', 'sport'), ('obj2', 'http://www.wikidata.org/entity/Q847'), ('objName2', 'tennis')]
# [('objName', '2007 Tennis Masters Cup'), ('p', 'http://www.wikidata.org/prop/direct/P664'), ('pName', 'organizer'), ('obj2', 'http://www.wikidata.org/entity/Q744089'), ('objName2', 'Association of Tennis Professionals')]
# [('objName', '2007 Tennis Masters Cup'), ('p', 'http://www.wikidata.org/prop/direct/P910'), ('pName', "topic's main category"), ('obj2', 'http://www.wikidata.org/entity/Q8192907'), ('objName2', 'Category:2007 Tennis Masters Cup')]
# [('objName', "2010 Australian Open – Men's Singles"), ('p', 'http://www.wikidata.org/prop/direct/P17'), ('pName', 'country'), ('obj2', 'http://www.wikidata.org/entity/Q408'), ('objName2', 'Australia')]
# [('objName', "2010 Australian Open – Men's Singles"), ('p', 'http://www.wikidata.org/prop/direct/P2094'), ('pName', 'competition class'), ('obj2', 'http://www.wikidata.org/entity/Q16893072'), ('objName2', "men's singles")]
# [('objName', "2010 Australian Open – Men's Singles"), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj2', 'http://www.wikidata.org/entity/Q46190676'), ('objName2', 'tennis event')]
# [('objName', "2010 Australian Open – Men's Singles"), ('p', 'http://www.wikidata.org/prop/direct/P361'), ('pName', 'part of'), ('obj2', 'http://www.wikidata.org/entity/Q476646'), ('objName2', '2010 Australian Open')]
# [('objName', "2010 Australian Open – Men's Singles"), ('p', 'http://www.wikidata.org/prop/direct/P641'), ('pName', 'sport'), ('obj2', 'http://www.wikidata.org/entity/Q847'), ('objName2', 'tennis')]
# [('objName', "2006 Australian Open – Men's Singles"), ('p', 'http://www.wikidata.org/prop/direct/P17'), ('pName', 'country'), ('obj2', 'http://www.wikidata.org/entity/Q408'), ('objName2', 'Australia')]
# [('objName', "2006 Australian Open – Men's Singles"), ('p', 'http://www.wikidata.org/prop/direct/P2094'), ('pName', 'competition class'), ('obj2', 'http://www.wikidata.org/entity/Q16893072'), ('objName2', "men's singles")]
# [('objName', "2006 Australian Open – Men's Singles"), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj2', 'http://www.wikidata.org/entity/Q46190676'), ('objName2', 'tennis event')]
# [('objName', "2006 Australian Open – Men's Singles"), ('p', 'http://www.wikidata.org/prop/direct/P361'), ('pName', 'part of'), ('obj2', 'http://www.wikidata.org/entity/Q598746'), ('objName2', '2006 Australian Open')]
# [('objName', "2006 Australian Open – Men's Singles"), ('p', 'http://www.wikidata.org/prop/direct/P641'), ('pName', 'sport'), ('obj2', 'http://www.wikidata.org/entity/Q847'), ('objName2', 'tennis')]
# [('objName', '2011 ATP World Tour Finals'), ('p', 'http://www.wikidata.org/prop/direct/P17'), ('pName', 'country'), ('obj2', 'http://www.wikidata.org/entity/Q145'), ('objName2', 'United Kingdom')]
# [('objName', '2011 ATP World Tour Finals'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj2', 'http://www.wikidata.org/entity/Q270907'), ('objName2', 'ATP Finals')]
# [('objName', '2011 ATP World Tour Finals'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj2', 'http://www.wikidata.org/entity/Q47345468'), ('objName2', 'tennis tournament edition')]
# [('objName', '2011 ATP World Tour Finals'), ('p', 'http://www.wikidata.org/prop/direct/P3450'), ('pName', 'sports season of league or competition'), ('obj2', 'http://www.wikidata.org/entity/Q270907'), ('objName2', 'ATP Finals')]
# [('objName', '2011 ATP World Tour Finals'), ('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('obj2', 'http://www.wikidata.org/entity/Q2478962'), ('objName2', '2011 ATP World Tour Finals – singles')]
# [('objName', '2011 ATP World Tour Finals'), ('p', 'http://www.wikidata.org/prop/direct/P641'), ('pName', 'sport'), ('obj2', 'http://www.wikidata.org/entity/Q847'), ('objName2', 'tennis')]
# [('objName', '2011 ATP World Tour Finals'), ('p', 'http://www.wikidata.org/prop/direct/P664'), ('pName', 'organizer'), ('obj2', 'http://www.wikidata.org/entity/Q744089'), ('objName2', 'Association of Tennis Professionals')]
# [('objName', '2011 ATP World Tour Finals'), ('p', 'http://www.wikidata.org/prop/direct/P910'), ('pName', "topic's main category"), ('obj2', 'http://www.wikidata.org/entity/Q8983755'), ('objName2', 'Category:2011 ATP World Tour Finals')]
# [('objName', "2012 Wimbledon Championships – Gentlemen's Singles"), ('p', 'http://www.wikidata.org/prop/direct/P17'), ('pName', 'country'), ('obj2', 'http://www.wikidata.org/entity/Q145'), ('objName2', 'United Kingdom')]
# [('objName', "2012 Wimbledon Championships – Gentlemen's Singles"), ('p', 'http://www.wikidata.org/prop/direct/P2094'), ('pName', 'competition class'), ('obj2', 'http://www.wikidata.org/entity/Q16893072'), ('objName2', "men's singles")]
# [('objName', "2012 Wimbledon Championships – Gentlemen's Singles"), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj2', 'http://www.wikidata.org/entity/Q46190676'), ('objName2', 'tennis event')]
# [('objName', "2012 Wimbledon Championships – Gentlemen's Singles"), ('p', 'http://www.wikidata.org/prop/direct/P361'), ('pName', 'part of'), ('obj2', 'http://www.wikidata.org/entity/Q289587'), ('objName2', '2012 Wimbledon Championships')]
# [('objName', "2012 Wimbledon Championships – Gentlemen's Singles"), ('p', 'http://www.wikidata.org/prop/direct/P641'), ('pName', 'sport'), ('obj2', 'http://www.wikidata.org/entity/Q847'), ('objName2', 'tennis')]
# [('objName', "tennis at the 2008 Summer Olympics – men's doubles"), ('p', 'http://www.wikidata.org/prop/direct/P17'), ('pName', 'country'), ('obj2', 'http://www.wikidata.org/entity/Q148'), ('objName2', "People's Republic of China")]
# [('objName', "tennis at the 2008 Summer Olympics – men's doubles"), ('p', 'http://www.wikidata.org/prop/direct/P2094'), ('pName', 'competition class'), ('obj2', 'http://www.wikidata.org/entity/Q17299700'), ('objName2', "men's doubles")]
# [('objName', "tennis at the 2008 Summer Olympics – men's doubles"), ('p', 'http://www.wikidata.org/prop/direct/P276'), ('pName', 'location'), ('obj2', 'http://www.wikidata.org/entity/Q1763829'), ('objName2', 'National Tennis Center, Beijing')]
# [('objName', "tennis at the 2008 Summer Olympics – men's doubles"), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj2', 'http://www.wikidata.org/entity/Q18536594'), ('objName2', 'Olympic sporting event')]
# [('objName', "tennis at the 2008 Summer Olympics – men's doubles"), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj2', 'http://www.wikidata.org/entity/Q46190676'), ('objName2', 'tennis event')]
# [('objName', "tennis at the 2008 Summer Olympics – men's doubles"), ('p', 'http://www.wikidata.org/prop/direct/P361'), ('pName', 'part of'), ('obj2', 'http://www.wikidata.org/entity/Q194246'), ('objName2', 'tennis at the 2008 Summer Olympics')]
# [('objName', "tennis at the 2008 Summer Olympics – men's doubles"), ('p', 'http://www.wikidata.org/prop/direct/P641'), ('pName', 'sport'), ('obj2', 'http://www.wikidata.org/entity/Q847'), ('objName2', 'tennis')]
# [('objName', "2006 Wimbledon Championships – Men's Singles"), ('p', 'http://www.wikidata.org/prop/direct/P17'), ('pName', 'country'), ('obj2', 'http://www.wikidata.org/entity/Q145'), ('objName2', 'United Kingdom')]
# [('objName', "2006 Wimbledon Championships – Men's Singles"), ('p', 'http://www.wikidata.org/prop/direct/P2094'), ('pName', 'competition class'), ('obj2', 'http://www.wikidata.org/entity/Q16893072'), ('objName2', "men's singles")]
# [('objName', "2006 Wimbledon Championships – Men's Singles"), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj2', 'http://www.wikidata.org/entity/Q46190676'), ('objName2', 'tennis event')]
# [('objName', "2006 Wimbledon Championships – Men's Singles"), ('p', 'http://www.wikidata.org/prop/direct/P361'), ('pName', 'part of'), ('obj2', 'http://www.wikidata.org/entity/Q241184'), ('objName2', '2006 Wimbledon Championships')]
# [('objName', "2006 Wimbledon Championships – Men's Singles"), ('p', 'http://www.wikidata.org/prop/direct/P641'), ('pName', 'sport'), ('obj2', 'http://www.wikidata.org/entity/Q847'), ('objName2', 'tennis')]
# [('objName', "2005 Wimbledon Championships – Men's Singles"), ('p', 'http://www.wikidata.org/prop/direct/P17'), ('pName', 'country'), ('obj2', 'http://www.wikidata.org/entity/Q145'), ('objName2', 'United Kingdom')]
# [('objName', "2005 Wimbledon Championships – Men's Singles"), ('p', 'http://www.wikidata.org/prop/direct/P2094'), ('pName', 'competition class'), ('obj2', 'http://www.wikidata.org/entity/Q16893072'), ('objName2', "men's singles")]
# 50

# %%
# Return the four Grand Slam of tennis (hint: One of these four is Wimbledon) 
#   (the result set must be a list of four couples Grand Slam IRI and label).

# Roger Federer (wd:Q1426)
# tennis player (wd:Q10833314)
# winner (wdt:P1346)
# "tennis at the 2000 Summer Olympics – men's singles" (wd:Q589310)
# sport (wdt:P641)
# instance of (wdt:P31)
# tennis event (wd:Q46190676)
# wd:Q47459169 tennis match
# wd:Q21170330 tennis qualification event
# wd:Q16510064 sporting event
# wd:Q47345468 tennis tournament edition
# wd:Q847 tennis
# wd:Q223041 International Tennis Federation
# part of (wdt:P361) 
# wd:Q13219666 'tennis tournament'

# wdt:P2522 'victory' 
# wd:Q782589 "2010 Australian Open – Men's Singles"

# ('obj2', 'http://www.wikidata.org/entity/Q270907'), ('objName2', 'ATP Finals')]

# trying to see where I can get from "ATP Finals" (wd:Q270907)

queryString = """
SELECT DISTINCT ?p ?pName ?obj ?objName 
WHERE {
   # bind something
   wd:Q270907 ?p ?obj .
   # get the label
   # ?p sc:name ?pName.
   # ?obj sc:name ?objName.
}
LIMIT 50

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q47443726'), ('objName', 'recurring tennis tournament')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('obj', 'http://www.wikidata.org/entity/Q26863790'), ('objName', 'ATP tennis tournament')]
# [('p', 'http://www.wikidata.org/prop/direct/P276'), ('pName', 'location'), ('obj', 'http://www.wikidata.org/entity/Q5364202'), ('objName', 'The O2 Arena')]
# [('p', 'http://www.wikidata.org/prop/direct/P765'), ('pName', 'surface played on'), ('obj', 'http://www.wikidata.org/entity/Q1330871'), ('objName', 'hardcourt')]
# [('p', 'http://www.wikidata.org/prop/direct/P17'), ('pName', 'country'), ('obj', 'http://www.wikidata.org/entity/Q145'), ('objName', 'United Kingdom')]
# [('p', 'http://www.wikidata.org/prop/direct/P664'), ('pName', 'organizer'), ('obj', 'http://www.wikidata.org/entity/Q744089'), ('objName', 'Association of Tennis Professionals')]
# [('p', 'http://www.wikidata.org/prop/direct/P641'), ('pName', 'sport'), ('obj', 'http://www.wikidata.org/entity/Q847'), ('objName', 'tennis')]
# [('p', 'http://www.wikidata.org/prop/direct/P361'), ('pName', 'part of'), ('obj', 'http://www.wikidata.org/entity/Q300008'), ('objName', 'ATP Tour')]
# [('p', 'http://www.wikidata.org/prop/direct/P910'), ('pName', "topic's main category"), ('obj', 'http://www.wikidata.org/entity/Q8217931'), ('objName', 'Category:ATP Finals')]
# 9

# %%
# Return the four Grand Slam of tennis (hint: One of these four is Wimbledon) 
#   (the result set must be a list of four couples Grand Slam IRI and label).

# Roger Federer (wd:Q1426)
# tennis player (wd:Q10833314)
# winner (wdt:P1346)
# "tennis at the 2000 Summer Olympics – men's singles" (wd:Q589310)
# sport (wdt:P641)
# instance of (wdt:P31)
# tennis event (wd:Q46190676)
# wd:Q47459169 tennis match
# wd:Q21170330 tennis qualification event
# wd:Q16510064 sporting event
# wd:Q47345468 tennis tournament edition
# wd:Q847 tennis
# wd:Q223041 International Tennis Federation
# part of (wdt:P361) 
# wd:Q13219666 'tennis tournament'

# wdt:P2522 'victory' 
# wd:Q782589 "2010 Australian Open – Men's Singles"
# wd:Q270907 'ATP Finals'
# wd:Q47443726 'recurring tennis tournament'

# trying to see where I can get from "recurring tennis tournament" (wd:Q47443726)

queryString = """
SELECT DISTINCT ?p ?pName ?obj ?objName 
WHERE {
   # bind something
   wd:Q47443726 ?p ?obj .
   # get the label
   # ?p sc:name ?pName.
   # ?obj sc:name ?objName.
}
LIMIT 50

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('obj', 'http://www.wikidata.org/entity/Q15259995'), ('objName', 'recurring tournament')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('obj', 'http://www.wikidata.org/entity/P576'), ('objName', 'dissolved, abolished or demolished date')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('obj', 'http://www.wikidata.org/entity/P17'), ('objName', 'country')]
# [('p', 'http://www.wikidata.org/prop/direct/P641'), ('pName', 'sport'), ('obj', 'http://www.wikidata.org/entity/Q847'), ('objName', 'tennis')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('obj', 'http://www.wikidata.org/entity/P571'), ('objName', 'inception')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('obj', 'http://www.wikidata.org/entity/P856'), ('objName', 'official website')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('obj', 'http://www.wikidata.org/entity/P641'), ('objName', 'sport')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('obj', 'http://www.wikidata.org/entity/P910'), ('objName', "topic's main category")]
# [('p', 'http://www.wikidata.org/prop/direct/P2670'), ('pName', 'has parts of the class'), ('obj', 'http://www.wikidata.org/entity/Q47345468'), ('objName', 'tennis tournament edition')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('obj', 'http://www.wikidata.org/entity/P276'), ('objName', 'location')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('obj', 'http://www.wikidata.org/entity/P2257'), ('objName', 'event interval')]
# [('p', 'http://www.wikidata.org/prop/direct/P2670'), ('pName', 'has parts of the class'), ('obj', 'http://www.wikidata.org/entity/Q47482648'), ('objName', 'tennis tournament by gender')]
# 12

# %%
# Return the four Grand Slam of tennis (hint: One of these four is Wimbledon) 
#   (the result set must be a list of four couples Grand Slam IRI and label).

# Roger Federer (wd:Q1426)
# tennis player (wd:Q10833314)
# winner (wdt:P1346)
# "tennis at the 2000 Summer Olympics – men's singles" (wd:Q589310)
# sport (wdt:P641)
# instance of (wdt:P31)
# tennis event (wd:Q46190676)
# wd:Q47459169 tennis match
# wd:Q21170330 tennis qualification event
# wd:Q16510064 sporting event
# wd:Q47345468 tennis tournament edition
# wd:Q847 tennis
# wd:Q223041 International Tennis Federation
# part of (wdt:P361) 
# wd:Q13219666 'tennis tournament'

# wdt:P2522 'victory' 
# wd:Q782589 "2010 Australian Open – Men's Singles"
# wd:Q270907 'ATP Finals'
# wd:Q47443726 'recurring tennis tournament'

# trying to see where I can get from "recurring tennis tournament" (wd:Q47443726)

queryString = """
SELECT DISTINCT ?p ?pName ?obj ?objName 
WHERE {
   # bind something
   wd:Q47443726 ?p ?obj .
   # get the label
   # ?p sc:name ?pName.
   # ?obj sc:name ?objName.
}
LIMIT 50

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('obj', 'http://www.wikidata.org/entity/Q15259995'), ('objName', 'recurring tournament')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('obj', 'http://www.wikidata.org/entity/P576'), ('objName', 'dissolved, abolished or demolished date')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('obj', 'http://www.wikidata.org/entity/P17'), ('objName', 'country')]
# [('p', 'http://www.wikidata.org/prop/direct/P641'), ('pName', 'sport'), ('obj', 'http://www.wikidata.org/entity/Q847'), ('objName', 'tennis')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('obj', 'http://www.wikidata.org/entity/P571'), ('objName', 'inception')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('obj', 'http://www.wikidata.org/entity/P856'), ('objName', 'official website')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('obj', 'http://www.wikidata.org/entity/P641'), ('objName', 'sport')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('obj', 'http://www.wikidata.org/entity/P910'), ('objName', "topic's main category")]
# [('p', 'http://www.wikidata.org/prop/direct/P2670'), ('pName', 'has parts of the class'), ('obj', 'http://www.wikidata.org/entity/Q47345468'), ('objName', 'tennis tournament edition')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('obj', 'http://www.wikidata.org/entity/P276'), ('objName', 'location')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('obj', 'http://www.wikidata.org/entity/P2257'), ('objName', 'event interval')]
# [('p', 'http://www.wikidata.org/prop/direct/P2670'), ('pName', 'has parts of the class'), ('obj', 'http://www.wikidata.org/entity/Q47482648'), ('objName', 'tennis tournament by gender')]
# 12

# %%
## REVERSE QUERY

# %%
# Return the four Grand Slam of tennis (hint: One of these four is Wimbledon) 
#   (the result set must be a list of four couples Grand Slam IRI and label).

# Roger Federer (wd:Q1426)
# tennis player (wd:Q10833314)
# winner (wdt:P1346)
# "tennis at the 2000 Summer Olympics – men's singles" (wd:Q589310)
# sport (wdt:P641)
# instance of (wdt:P31)
# tennis event (wd:Q46190676)
# wd:Q47459169 tennis match
# wd:Q21170330 tennis qualification event
# wd:Q16510064 sporting event
# wd:Q47345468 tennis tournament edition
# wd:Q847 tennis
# wd:Q223041 International Tennis Federation
# part of (wdt:P361) 
# wd:Q13219666 'tennis tournament'

# wdt:P2522 'victory' 
# wd:Q782589 "2010 Australian Open – Men's Singles"
# wd:Q270907 'ATP Finals'
# wd:Q47443726 'recurring tennis tournament'

# trying to see where I can get from "recurring tennis tournament" (wd:Q47443726) BACKWARD SEARCH
queryString = """
SELECT ?p ?pName ?obj ?objName
WHERE {
   # bind something
   # ?obj ?p wd:Q47443726 .
   # get the label
   # ?p sc:name ?pName.
   # ?obj sc:name ?objName.
}
LIMIT 50

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q299931'), ('objName', 'Chile Open')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q15729796'), ('objName', 'State Bank of India ATP Challenger Tour')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q17306815'), ('objName', 'USTA Player Development Classic')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q17333223'), ('objName', 'UTF Cup')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q17464028'), ('objName', "ITF Women's Circuit – Wuhan")]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q13528155'), ('objName', "ITF Women's Circuit UBS Thurgau")]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q17493278'), ('objName', 'International Tennis Tournament of Cortina')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q24911704'), ('objName', 'Zhengzhou Open')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q22235842'), ('objName', 'Manila Challenger')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q26265946'), ('objName', 'Torneo de Tenis Feria de Mérida')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q26268650'), ('objName', 'ZS-Sports China International Challenger')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q26307058'), ('objName', 'Adriatic Challenger')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q27220048'), ('objName', 'Stockton ATP Challenger')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q20010797'), ('objName', 'Internazionali di Tennis Città di Vicenza')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q1612985'), ('objName', 'WTA Madrid Open')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q755314'), ('objName', 'Charleston Open')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q270907'), ('objName', 'ATP Finals')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q595467'), ('objName', 'Canadian Open')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q906441'), ('objName', 'Southern California Open')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q739723'), ('objName', 'Pan Pacific Open')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q1852401'), ('objName', 'Ameritech Cup')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q838761'), ('objName', 'Hobart International')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q121702'), ('objName', 'China Open')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q1762314'), ('objName', 'Danamon Open')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q1940040'), ('objName', 'Croatian Bol Ladies Open')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q3353485'), ('objName', 'Denver Open')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q3353695'), ('objName', 'Puerto Rico Open')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q4017086'), ('objName', 'WTA Argentine Open')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q558225'), ('objName', 'PTT Pattaya Open')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q905666'), ('objName', "LA Women's Tennis Championships")]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q299406'), ('objName', 'Power Horse Cup')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q15249370'), ('objName', 'PTT İstanbul Cup')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q21055686'), ('objName', 'Columbus Challenger')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q47487971'), ('objName', 'Calgary Challenger')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q2999429'), ('objName', 'Aberavon Cup')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q28739880'), ('objName', 'Eastern Mediterranean Championship Tennis')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q299126'), ('objName', 'Dutch Open')]
# [('p', 'http://www.wikidata.org/prop/direct/P2670'), ('pName', 'has parts of the class'), ('obj', 'http://www.wikidata.org/entity/Q7700500'), ('objName', 'tennis tour')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q169947'), ('objName', 'Memphis Open')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q220347'), ('objName', 'WTA Finals')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q248952'), ('objName', 'Sydney International')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q4017348'), ('objName', 'Sydney International (women)')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q299176'), ('objName', 'Serbia Open (men)')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q299235'), ('objName', 'Swedish Open')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q299622'), ('objName', 'Hall of Fame Open')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q461834'), ('objName', 'Cincinnati Masters')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q431360'), ('objName', 'Miami Open')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q842047'), ('objName', 'Warsaw Open')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q392385'), ('objName', 'National Bank Cup')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q660558'), ('objName', 'Generali Ladies Linz')]
# 50

# %%
# Return the four Grand Slam of tennis (hint: One of these four is Wimbledon) 
#   (the result set must be a list of four couples Grand Slam IRI and label).

# Roger Federer (wd:Q1426)
# tennis player (wd:Q10833314)
# winner (wdt:P1346)
# "tennis at the 2000 Summer Olympics – men's singles" (wd:Q589310)
# sport (wdt:P641)
# instance of (wdt:P31)
# tennis event (wd:Q46190676)
# wd:Q47459169 tennis match
# wd:Q21170330 tennis qualification event
# wd:Q16510064 sporting event
# wd:Q47345468 tennis tournament edition
# wd:Q847 tennis
# wd:Q223041 International Tennis Federation
# part of (wdt:P361) 
# wd:Q13219666 'tennis tournament'

# wdt:P2522 'victory' 
# wd:Q782589 "2010 Australian Open – Men's Singles"
# wd:Q270907 'ATP Finals'
# wd:Q47443726 'recurring tennis tournament'

# trying to see where I can get from "recurring tennis tournament" (wd:Q47443726) BACKWARD SEARCH
# using GROUPING

queryString = """
SELECT ?obj ?objName (count(*) as ?totCount)
WHERE {
   # bind something
   # ?obj ?p wd:Q47443726 .
   # get the label
   # ?p sc:name ?pName.
   # ?obj sc:name ?objName.
}
GROUP BY ?obj ?objName
ORDER BY desc (?totCount)
LIMIT 50

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('obj', 'http://www.wikidata.org/entity/Q270907'), ('objName', 'ATP Finals'), ('totCount', '1')]
# [('obj', 'http://www.wikidata.org/entity/Q906441'), ('objName', 'Southern California Open'), ('totCount', '1')]
# [('obj', 'http://www.wikidata.org/entity/Q3353485'), ('objName', 'Denver Open'), ('totCount', '1')]
# [('obj', 'http://www.wikidata.org/entity/Q15249370'), ('objName', 'PTT İstanbul Cup'), ('totCount', '1')]
# [('obj', 'http://www.wikidata.org/entity/Q592389'), ('objName', 'Internazionali Femminili di Palermo'), ('totCount', '1')]
# [('obj', 'http://www.wikidata.org/entity/Q299914'), ('objName', 'Valencia Open 250'), ('totCount', '1')]
# [('obj', 'http://www.wikidata.org/entity/Q299532'), ('objName', 'Madrid Tennis Grand Prix'), ('totCount', '1')]
# [('obj', 'http://www.wikidata.org/entity/Q3843957'), ('objName', 'Mallorca Challenger'), ('totCount', '1')]
# [('obj', 'http://www.wikidata.org/entity/Q47487928'), ('objName', 'Punta Open'), ('totCount', '1')]
# [('obj', 'http://www.wikidata.org/entity/Q3772892'), ('objName', 'Gold Fields St Ives Tennis International'), ('totCount', '1')]
# [('obj', 'http://www.wikidata.org/entity/Q299603'), ('objName', 'Kremlin Cup'), ('totCount', '1')]
# [('obj', 'http://www.wikidata.org/entity/Q299701'), ('objName', 'Rotterdam Open'), ('totCount', '1')]
# [('obj', 'http://www.wikidata.org/entity/Q20656604'), ('objName', 'WTA New Jersey'), ('totCount', '1')]
# [('obj', 'http://www.wikidata.org/entity/Q299189'), ('objName', 'Bologna Outdoor'), ('totCount', '1')]
# [('obj', 'http://www.wikidata.org/entity/Q3705902'), ('objName', 'Des Moines Open'), ('totCount', '1')]
# [('obj', 'http://www.wikidata.org/entity/Q3999229'), ('objName', 'Trofeo Bonfiglio'), ('totCount', '1')]
# [('obj', 'http://www.wikidata.org/entity/Q555063'), ('objName', 'Eurocard Open'), ('totCount', '1')]
# [('obj', 'http://www.wikidata.org/entity/Q3870211'), ('objName', 'Napa Open'), ('totCount', '1')]
# [('obj', 'http://www.wikidata.org/entity/Q17021287'), ('objName', 'WTA Atlanta'), ('totCount', '1')]
# [('obj', 'http://www.wikidata.org/entity/Q1991081'), ('objName', 'National Panasonic Open'), ('totCount', '1')]
# [('obj', 'http://www.wikidata.org/entity/Q25378154'), ('objName', 'Morocco Tennis Tour – Casablanca II'), ('totCount', '1')]
# [('obj', 'http://www.wikidata.org/entity/Q299706'), ('objName', 'SAP Open'), ('totCount', '1')]
# [('obj', 'http://www.wikidata.org/entity/Q74705'), ('objName', 'World Hard Court Championships'), ('totCount', '1')]
# [('obj', 'http://www.wikidata.org/entity/Q19891914'), ('objName', 'Indore Open ATP Challenger'), ('totCount', '1')]
# [('obj', 'http://www.wikidata.org/entity/Q18287737'), ('objName', 'Bredeney Ladies Open'), ('totCount', '1')]
# [('obj', 'http://www.wikidata.org/entity/Q30644268'), ('objName', 'Aegon Southsea Trophy'), ('totCount', '1')]
# [('obj', 'http://www.wikidata.org/entity/Q47006610'), ('objName', 'Rio Tennis Classic'), ('totCount', '1')]
# [('obj', 'http://www.wikidata.org/entity/Q300009'), ('objName', 'Winston-Salem Open'), ('totCount', '1')]
# [('obj', 'http://www.wikidata.org/entity/Q41799397'), ('objName', 'Wolffkran Open'), ('totCount', '1')]
# [('obj', 'http://www.wikidata.org/entity/Q47832385'), ('objName', 'tennis at the South American Games'), ('totCount', '1')]
# [('obj', 'http://www.wikidata.org/entity/Q28976348'), ('objName', 'International Challenger Quanzhou'), ('totCount', '1')]
# [('obj', 'http://www.wikidata.org/entity/Q22079851'), ('objName', 'China International Suzhou'), ('totCount', '1')]
# [('obj', 'http://www.wikidata.org/entity/Q2999845'), ('objName', 'Billingham Cup'), ('totCount', '1')]
# [('obj', 'http://www.wikidata.org/entity/Q1764600'), ('objName', 'Ilva Trophy'), ('totCount', '1')]
# [('obj', 'http://www.wikidata.org/entity/Q3787550'), ('objName', 'Hull Challenger'), ('totCount', '1')]
# [('obj', 'http://www.wikidata.org/entity/Q3854150'), ('objName', 'Melbourne Outdoor'), ('totCount', '1')]
# [('obj', 'http://www.wikidata.org/entity/Q3601888'), ('objName', 'ATP Luxembourg'), ('totCount', '1')]
# [('obj', 'http://www.wikidata.org/entity/Q3929662'), ('objName', 'Rainier International Tennis Classic'), ('totCount', '1')]
# [('obj', 'http://www.wikidata.org/entity/Q17122092'), ('objName', 'Venice Challenge Save Cup'), ('totCount', '1')]
# [('obj', 'http://www.wikidata.org/entity/Q50185613'), ('objName', 'Qujing International Challenger'), ('totCount', '1')]
# [('obj', 'http://www.wikidata.org/entity/Q559650'), ('objName', 'Caloundra International'), ('totCount', '1')]
# [('obj', 'http://www.wikidata.org/entity/Q15731893'), ('objName', 'ONGC–GAIL Delhi Open'), ('totCount', '1')]
# [('obj', 'http://www.wikidata.org/entity/Q23038902'), ('objName', 'Zhuhai Open'), ('totCount', '1')]
# [('obj', 'http://www.wikidata.org/entity/Q3994517'), ('objName', 'Torneo Internacional de Tenis Sant Cugat'), ('totCount', '1')]
# [('obj', 'http://www.wikidata.org/entity/Q6952969'), ('objName', 'NCAA Lawn Tennis Championship'), ('totCount', '1')]
# [('obj', 'http://www.wikidata.org/entity/Q3690973'), ('objName', 'Copenhagen Challenger'), ('totCount', '1')]
# [('obj', 'http://www.wikidata.org/entity/Q12335564'), ('objName', 'Scandinavian Indoor Championships'), ('totCount', '1')]
# [('obj', 'http://www.wikidata.org/entity/Q28219768'), ('objName', 'Quito Open'), ('totCount', '1')]
# [('obj', 'http://www.wikidata.org/entity/Q55392005'), ('objName', 'Berkeley Tennis Club Challenge'), ('totCount', '1')]
# [('obj', 'http://www.wikidata.org/entity/Q28434536'), ('objName', 'Scottish Championships'), ('totCount', '1')]
# 50

# %%
# Return the four Grand Slam of tennis (hint: One of these four is Wimbledon) 
#   (the result set must be a list of four couples Grand Slam IRI and label).

# Roger Federer (wd:Q1426)
# tennis player (wd:Q10833314)
# winner (wdt:P1346)
# "tennis at the 2000 Summer Olympics – men's singles" (wd:Q589310)
# sport (wdt:P641)
# instance of (wdt:P31)
# tennis event (wd:Q46190676)
# wd:Q47459169 tennis match
# wd:Q21170330 tennis qualification event
# wd:Q16510064 sporting event
# wd:Q47345468 tennis tournament edition
# wd:Q847 tennis
# wd:Q223041 International Tennis Federation
# part of (wdt:P361) 
# wd:Q13219666 'tennis tournament'

# wdt:P2522 'victory' 
# wd:Q782589 "2010 Australian Open – Men's Singles"
# wd:Q270907 'ATP Finals'
# wd:Q47443726 'recurring tennis tournament'

# trying to see where I can get from "recurring tennis tournament" (wd:Q47443726) BACKWARD SEARCH
# extending LIMIT to 100
queryString = """
SELECT ?p ?pName ?obj ?objName
WHERE {
   # bind something
   # ?obj ?p wd:Q47443726 .
   # get the label
   # ?p sc:name ?pName.
   # ?obj sc:name ?objName.
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q299931'), ('objName', 'Chile Open')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q15729796'), ('objName', 'State Bank of India ATP Challenger Tour')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q17306815'), ('objName', 'USTA Player Development Classic')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q17333223'), ('objName', 'UTF Cup')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q17464028'), ('objName', "ITF Women's Circuit – Wuhan")]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q13528155'), ('objName', "ITF Women's Circuit UBS Thurgau")]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q17493278'), ('objName', 'International Tennis Tournament of Cortina')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q24911704'), ('objName', 'Zhengzhou Open')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q22235842'), ('objName', 'Manila Challenger')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q26265946'), ('objName', 'Torneo de Tenis Feria de Mérida')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q26268650'), ('objName', 'ZS-Sports China International Challenger')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q26307058'), ('objName', 'Adriatic Challenger')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q27220048'), ('objName', 'Stockton ATP Challenger')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q20010797'), ('objName', 'Internazionali di Tennis Città di Vicenza')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q1612985'), ('objName', 'WTA Madrid Open')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q755314'), ('objName', 'Charleston Open')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q270907'), ('objName', 'ATP Finals')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q595467'), ('objName', 'Canadian Open')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q906441'), ('objName', 'Southern California Open')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q739723'), ('objName', 'Pan Pacific Open')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q1852401'), ('objName', 'Ameritech Cup')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q838761'), ('objName', 'Hobart International')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q121702'), ('objName', 'China Open')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q1762314'), ('objName', 'Danamon Open')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q1940040'), ('objName', 'Croatian Bol Ladies Open')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q3353485'), ('objName', 'Denver Open')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q3353695'), ('objName', 'Puerto Rico Open')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q4017086'), ('objName', 'WTA Argentine Open')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q558225'), ('objName', 'PTT Pattaya Open')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q905666'), ('objName', "LA Women's Tennis Championships")]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q299406'), ('objName', 'Power Horse Cup')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q15249370'), ('objName', 'PTT İstanbul Cup')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q21055686'), ('objName', 'Columbus Challenger')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q47487971'), ('objName', 'Calgary Challenger')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q2999429'), ('objName', 'Aberavon Cup')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q28739880'), ('objName', 'Eastern Mediterranean Championship Tennis')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q299126'), ('objName', 'Dutch Open')]
# [('p', 'http://www.wikidata.org/prop/direct/P2670'), ('pName', 'has parts of the class'), ('obj', 'http://www.wikidata.org/entity/Q7700500'), ('objName', 'tennis tour')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q169947'), ('objName', 'Memphis Open')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q220347'), ('objName', 'WTA Finals')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q248952'), ('objName', 'Sydney International')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q4017348'), ('objName', 'Sydney International (women)')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q299176'), ('objName', 'Serbia Open (men)')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q299235'), ('objName', 'Swedish Open')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q299622'), ('objName', 'Hall of Fame Open')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q461834'), ('objName', 'Cincinnati Masters')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q431360'), ('objName', 'Miami Open')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q842047'), ('objName', 'Warsaw Open')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q392385'), ('objName', 'National Bank Cup')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q660558'), ('objName', 'Generali Ladies Linz')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q299174'), ('objName', 'Swiss Indoors')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q299685'), ('objName', "Queen's Club Championships")]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q300007'), ('objName', 'Erste Bank Open')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q459528'), ('objName', 'Monte-Carlo Masters')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q2951930'), ('objName', 'Welsh Championships')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q592389'), ('objName', 'Internazionali Femminili di Palermo')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q17151899'), ('objName', "ITF Women's Circuit – Xi'an")]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q18413540'), ('objName', 'WTA Elite Trophy')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q20807181'), ('objName', "Citta' di Vercelli – Trofeo Multimed")]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q1510835'), ('objName', 'Commonwealth Bank Tennis Classic')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q299144'), ('objName', 'Atlanta Open')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q299914'), ('objName', 'Valencia Open 250')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q299714'), ('objName', 'OTB Open')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q299532'), ('objName', 'Madrid Tennis Grand Prix')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('obj', 'http://www.wikidata.org/entity/Q3353551'), ('objName', 'Lorraine Open')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q3797954'), ('objName', 'Indian Open')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q3800183'), ('objName', 'Internazionali Femminili di Brescia')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q3816070'), ('objName', 'Købstædernes ATP Challenger')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q3820766'), ('objName', 'La Costa WCT')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q3827535'), ('objName', 'Latrobe City Tennis International')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q3835058'), ('objName', 'Arkansas International Tennis Tournament')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q3843957'), ('objName', 'Mallorca Challenger')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q3844309'), ('objName', 'Manchester Trophy Challenger')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q3844406'), ('objName', 'Mandeville Challenger')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('obj', 'http://www.wikidata.org/entity/Q3535028'), ('objName', 'Richmond WCT')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q3936244'), ('objName', 'Río de la Plata Challenger')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q3938141'), ('objName', 'Roanoke International Tennis Tournament')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q3941758'), ('objName', 'Rothmans International Tennis Tournament')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q3944106'), ('objName', 's Tennis Masters Challenger')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q3945759'), ('objName', 'Salou Challenger')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q3946307'), ('objName', 'ATP Challenger Salzburg-2')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q3959809'), ('objName', 'Shreveport Challenger')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q47487928'), ('objName', 'Punta Open')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q3600432'), ('objName', "AAT Women's Circuit Rosario")]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q3720749'), ('objName', 'ATP Challenger Eisenach')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q3772892'), ('objName', 'Gold Fields St Ives Tennis International')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q3817814'), ('objName', 'Kültürpark Cup')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q3843487'), ('objName', 'Maia Challenger')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q18194670'), ('objName', 'Claro Open Cali')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q23956839'), ('objName', 'Open Sopra Steria de Lyon')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q26869510'), ('objName', 'Internazionali di Tenis Femminili Città di Latina')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q28071051'), ('objName', 'Koblenz Open')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q17993729'), ('objName', 'Gazprom Hungarian Open')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q299454'), ('objName', 'Gerry Weber Open')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q7565760'), ('objName', 'South African Open')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q8496'), ('objName', 'Grand Prix de Tennis de Lyon')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q299745'), ('objName', 'Stockholm Open')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q667092'), ('objName', 'Zurich Open')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('obj', 'http://www.wikidata.org/entity/Q279800'), ('objName', 'U.S. Pro Indoor')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q431569'), ('objName', 'Eastbourne International')]
# 100

# %%
# Return the four Grand Slam of tennis (hint: One of these four is Wimbledon) 
#   (the result set must be a list of four couples Grand Slam IRI and label).

# Roger Federer (wd:Q1426)
# tennis player (wd:Q10833314)
# winner (wdt:P1346)
# "tennis at the 2000 Summer Olympics – men's singles" (wd:Q589310)
# sport (wdt:P641)
# instance of (wdt:P31)
# tennis event (wd:Q46190676)
# wd:Q47459169 tennis match
# wd:Q21170330 tennis qualification event
# wd:Q16510064 sporting event
# wd:Q47345468 tennis tournament edition
# wd:Q847 tennis
# wd:Q223041 International Tennis Federation
# part of (wdt:P361) 
# wd:Q13219666 'tennis tournament'

# wdt:P2522 'victory' 
# wd:Q782589 "2010 Australian Open – Men's Singles"
# wd:Q270907 'ATP Finals'
# wd:Q47443726 'recurring tennis tournament'

# CAN'T find any solution, lets restart from First Seed point Roger Federer's (wd:Q1426) victories 
# with extended limit

queryString = """
SELECT ?p ?pName ?obj ?objName
WHERE {
   # bind something
   wd:Q1426 wdt:P2522 ?obj.
   # ?obj sc:name ?objName.
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('obj', 'http://www.wikidata.org/entity/Q22956224'), ('objName', "2017 Australian Open – Men's Singles")]
# [('obj', 'http://www.wikidata.org/entity/Q612597'), ('objName', '2007 Tennis Masters Cup')]
# [('obj', 'http://www.wikidata.org/entity/Q782589'), ('objName', "2010 Australian Open – Men's Singles")]
# [('obj', 'http://www.wikidata.org/entity/Q782420'), ('objName', "2006 Australian Open – Men's Singles")]
# [('obj', 'http://www.wikidata.org/entity/Q300024'), ('objName', '2011 ATP World Tour Finals')]
# [('obj', 'http://www.wikidata.org/entity/Q753300'), ('objName', "2012 Wimbledon Championships – Gentlemen's Singles")]
# [('obj', 'http://www.wikidata.org/entity/Q757054'), ('objName', "tennis at the 2008 Summer Olympics – men's doubles")]
# [('obj', 'http://www.wikidata.org/entity/Q1074654'), ('objName', "2006 Wimbledon Championships – Men's Singles")]
# [('obj', 'http://www.wikidata.org/entity/Q384929'), ('objName', "2005 Wimbledon Championships – Men's Singles")]
# [('obj', 'http://www.wikidata.org/entity/Q14916861'), ('objName', '2014 Davis Cup')]
# [('obj', 'http://www.wikidata.org/entity/Q46993124'), ('objName', "2018 Australian Open – Men's Singles")]
# [('obj', 'http://www.wikidata.org/entity/Q964291'), ('objName', '2006 Tennis Masters Cup')]
# [('obj', 'http://www.wikidata.org/entity/Q300022'), ('objName', '2010 ATP World Tour Finals')]
# [('obj', 'http://www.wikidata.org/entity/Q1048953'), ('objName', "2004 US Open – Men's Singles")]
# [('obj', 'http://www.wikidata.org/entity/Q731509'), ('objName', "2005 US Open – Men's Singles")]
# [('obj', 'http://www.wikidata.org/entity/Q741573'), ('objName', "2009 French Open – Men's Singles")]
# [('obj', 'http://www.wikidata.org/entity/Q912506'), ('objName', "2006 US Open – Men's Singles")]
# [('obj', 'http://www.wikidata.org/entity/Q248965'), ('objName', "2004 Wimbledon Championships – Men's Singles")]
# [('obj', 'http://www.wikidata.org/entity/Q378627'), ('objName', "2003 Wimbledon Championships – Men's Singles")]
# [('obj', 'http://www.wikidata.org/entity/Q779654'), ('objName', "2004 Australian Open - men's singles")]
# [('obj', 'http://www.wikidata.org/entity/Q25344123'), ('objName', "2017 Wimbledon Championships – Men's Singles")]
# [('obj', 'http://www.wikidata.org/entity/Q2478340'), ('objName', '2011 BNP Paribas Masters – singles')]
# [('obj', 'http://www.wikidata.org/entity/Q751798'), ('objName', "2009 Wimbledon Championships – Men's Singles")]
# [('obj', 'http://www.wikidata.org/entity/Q782451'), ('objName', "2007 Australian Open – Men's Singles")]
# [('obj', 'http://www.wikidata.org/entity/Q912483'), ('objName', "2007 Wimbledon Championships – Men's Singles")]
# [('obj', 'http://www.wikidata.org/entity/Q304072'), ('objName', "2008 US Open – Men's Singles")]
# [('obj', 'http://www.wikidata.org/entity/Q2031910'), ('objName', '2003 Tennis Masters Cup')]
# [('obj', 'http://www.wikidata.org/entity/Q2094307'), ('objName', '2004 Tennis Masters Cup')]
# [('obj', 'http://www.wikidata.org/entity/Q836815'), ('objName', "2007 US Open – Men's Singles")]
# 29

# %%
# Return the four Grand Slam of tennis (hint: One of these four is Wimbledon) 
#   (the result set must be a list of four couples Grand Slam IRI and label).

# Roger Federer (wd:Q1426)
# tennis player (wd:Q10833314)
# winner (wdt:P1346)
# "tennis at the 2000 Summer Olympics – men's singles" (wd:Q589310)
# sport (wdt:P641)
# instance of (wdt:P31)
# tennis event (wd:Q46190676)
# wd:Q47459169 tennis match
# wd:Q21170330 tennis qualification event
# wd:Q16510064 sporting event
# wd:Q47345468 tennis tournament edition
# wd:Q847 tennis
# wd:Q223041 International Tennis Federation
# part of (wdt:P361) 
# wd:Q13219666 'tennis tournament'

# wdt:P2522 'victory' 
# wd:Q782589 "2010 Australian Open – Men's Singles"
# wd:Q270907 'ATP Finals'
# wd:Q47443726 'recurring tennis tournament'

# CAN'T find any solution, lets restart from First Seed point Roger Federer's (wd:Q1426) victories 
# with extended limit

queryString = """
SELECT ?obj ?objName
WHERE {
   # Roger Federer -victory-> ?obj
   wd:Q1426 wdt:P2522 ?obj.
   # ?obj sc:name ?objName.
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('obj', 'http://www.wikidata.org/entity/Q22956224'), ('objName', "2017 Australian Open – Men's Singles")]
# [('obj', 'http://www.wikidata.org/entity/Q612597'), ('objName', '2007 Tennis Masters Cup')]
# [('obj', 'http://www.wikidata.org/entity/Q782589'), ('objName', "2010 Australian Open – Men's Singles")]
# [('obj', 'http://www.wikidata.org/entity/Q782420'), ('objName', "2006 Australian Open – Men's Singles")]
# [('obj', 'http://www.wikidata.org/entity/Q300024'), ('objName', '2011 ATP World Tour Finals')]
# [('obj', 'http://www.wikidata.org/entity/Q753300'), ('objName', "2012 Wimbledon Championships – Gentlemen's Singles")]
# [('obj', 'http://www.wikidata.org/entity/Q757054'), ('objName', "tennis at the 2008 Summer Olympics – men's doubles")]
# [('obj', 'http://www.wikidata.org/entity/Q1074654'), ('objName', "2006 Wimbledon Championships – Men's Singles")]
# [('obj', 'http://www.wikidata.org/entity/Q384929'), ('objName', "2005 Wimbledon Championships – Men's Singles")]
# [('obj', 'http://www.wikidata.org/entity/Q14916861'), ('objName', '2014 Davis Cup')]
# [('obj', 'http://www.wikidata.org/entity/Q46993124'), ('objName', "2018 Australian Open – Men's Singles")]
# [('obj', 'http://www.wikidata.org/entity/Q964291'), ('objName', '2006 Tennis Masters Cup')]
# [('obj', 'http://www.wikidata.org/entity/Q300022'), ('objName', '2010 ATP World Tour Finals')]
# [('obj', 'http://www.wikidata.org/entity/Q1048953'), ('objName', "2004 US Open – Men's Singles")]
# [('obj', 'http://www.wikidata.org/entity/Q731509'), ('objName', "2005 US Open – Men's Singles")]
# [('obj', 'http://www.wikidata.org/entity/Q741573'), ('objName', "2009 French Open – Men's Singles")]
# [('obj', 'http://www.wikidata.org/entity/Q912506'), ('objName', "2006 US Open – Men's Singles")]
# [('obj', 'http://www.wikidata.org/entity/Q248965'), ('objName', "2004 Wimbledon Championships – Men's Singles")]
# [('obj', 'http://www.wikidata.org/entity/Q378627'), ('objName', "2003 Wimbledon Championships – Men's Singles")]
# [('obj', 'http://www.wikidata.org/entity/Q779654'), ('objName', "2004 Australian Open - men's singles")]
# [('obj', 'http://www.wikidata.org/entity/Q25344123'), ('objName', "2017 Wimbledon Championships – Men's Singles")]
# [('obj', 'http://www.wikidata.org/entity/Q2478340'), ('objName', '2011 BNP Paribas Masters – singles')]
# [('obj', 'http://www.wikidata.org/entity/Q751798'), ('objName', "2009 Wimbledon Championships – Men's Singles")]
# [('obj', 'http://www.wikidata.org/entity/Q782451'), ('objName', "2007 Australian Open – Men's Singles")]
# [('obj', 'http://www.wikidata.org/entity/Q912483'), ('objName', "2007 Wimbledon Championships – Men's Singles")]
# [('obj', 'http://www.wikidata.org/entity/Q304072'), ('objName', "2008 US Open – Men's Singles")]
# [('obj', 'http://www.wikidata.org/entity/Q2031910'), ('objName', '2003 Tennis Masters Cup')]
# [('obj', 'http://www.wikidata.org/entity/Q2094307'), ('objName', '2004 Tennis Masters Cup')]
# [('obj', 'http://www.wikidata.org/entity/Q836815'), ('objName', "2007 US Open – Men's Singles")]
# 29

# %%
## Roger Federer -victory-> ...

# %%
## Return the four Grand Slam of tennis (hint: One of these four is Wimbledon) (the result set must be a list of four couples Grand Slam IRI and label).

# Q1426 = Roger Federer -> P2522 = victory
    # Q782589 = 2010 Australian Open – Men's Singles
    # Q753300 = 2012 Wimbledon Championships
    # Q304072 = 2008 US Open – Men's Singles
    # Q741573 = 2009 French Open – Men's Singles

queryString = """
SELECT ?obj ?objName
WHERE {
   # Roger Federer -victory-> ?obj
   wd:Q1426 wdt:P2522 ?obj.
   # ?obj sc:name ?objName.
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('obj', 'http://www.wikidata.org/entity/Q22956224'), ('objName', "2017 Australian Open – Men's Singles")]
# [('obj', 'http://www.wikidata.org/entity/Q612597'), ('objName', '2007 Tennis Masters Cup')]
# [('obj', 'http://www.wikidata.org/entity/Q782589'), ('objName', "2010 Australian Open – Men's Singles")]
# [('obj', 'http://www.wikidata.org/entity/Q782420'), ('objName', "2006 Australian Open – Men's Singles")]
# [('obj', 'http://www.wikidata.org/entity/Q300024'), ('objName', '2011 ATP World Tour Finals')]
# [('obj', 'http://www.wikidata.org/entity/Q753300'), ('objName', "2012 Wimbledon Championships – Gentlemen's Singles")]
# [('obj', 'http://www.wikidata.org/entity/Q757054'), ('objName', "tennis at the 2008 Summer Olympics – men's doubles")]
# [('obj', 'http://www.wikidata.org/entity/Q1074654'), ('objName', "2006 Wimbledon Championships – Men's Singles")]
# [('obj', 'http://www.wikidata.org/entity/Q384929'), ('objName', "2005 Wimbledon Championships – Men's Singles")]
# [('obj', 'http://www.wikidata.org/entity/Q14916861'), ('objName', '2014 Davis Cup')]
# [('obj', 'http://www.wikidata.org/entity/Q46993124'), ('objName', "2018 Australian Open – Men's Singles")]
# [('obj', 'http://www.wikidata.org/entity/Q964291'), ('objName', '2006 Tennis Masters Cup')]
# [('obj', 'http://www.wikidata.org/entity/Q300022'), ('objName', '2010 ATP World Tour Finals')]
# [('obj', 'http://www.wikidata.org/entity/Q1048953'), ('objName', "2004 US Open – Men's Singles")]
# [('obj', 'http://www.wikidata.org/entity/Q731509'), ('objName', "2005 US Open – Men's Singles")]
# [('obj', 'http://www.wikidata.org/entity/Q741573'), ('objName', "2009 French Open – Men's Singles")]
# [('obj', 'http://www.wikidata.org/entity/Q912506'), ('objName', "2006 US Open – Men's Singles")]
# [('obj', 'http://www.wikidata.org/entity/Q248965'), ('objName', "2004 Wimbledon Championships – Men's Singles")]
# [('obj', 'http://www.wikidata.org/entity/Q378627'), ('objName', "2003 Wimbledon Championships – Men's Singles")]
# [('obj', 'http://www.wikidata.org/entity/Q779654'), ('objName', "2004 Australian Open - men's singles")]
# [('obj', 'http://www.wikidata.org/entity/Q25344123'), ('objName', "2017 Wimbledon Championships – Men's Singles")]
# [('obj', 'http://www.wikidata.org/entity/Q2478340'), ('objName', '2011 BNP Paribas Masters – singles')]
# [('obj', 'http://www.wikidata.org/entity/Q751798'), ('objName', "2009 Wimbledon Championships – Men's Singles")]
# [('obj', 'http://www.wikidata.org/entity/Q782451'), ('objName', "2007 Australian Open – Men's Singles")]
# [('obj', 'http://www.wikidata.org/entity/Q912483'), ('objName', "2007 Wimbledon Championships – Men's Singles")]
# [('obj', 'http://www.wikidata.org/entity/Q304072'), ('objName', "2008 US Open – Men's Singles")]
# [('obj', 'http://www.wikidata.org/entity/Q2031910'), ('objName', '2003 Tennis Masters Cup')]
# [('obj', 'http://www.wikidata.org/entity/Q2094307'), ('objName', '2004 Tennis Masters Cup')]
# [('obj', 'http://www.wikidata.org/entity/Q836815'), ('objName', "2007 US Open – Men's Singles")]
# 29

# %%
## Return the four Grand Slam of tennis (hint: One of these four is Wimbledon) (the result set must be a list of four couples Grand Slam IRI and label).

# Q1426 = Roger Federer -> P2522 = victory
    # Q782589 = 2010 Australian Open – Men's Singles
    # Q753300 = 2012 Wimbledon Championships
    # Q304072 = 2008 US Open – Men's Singles
    # Q741573 = 2009 French Open – Men's Singles
    
# trying to exprole backward from Q753300 = 2012 Wimbledon Championships

queryString = """
SELECT ?p ?pName ?obj ?objName
WHERE {
   # BACKWARD
   # ?obj ?p wd:Q753300 .
   # get the label
   # ?p sc:name ?pName.
   # ?obj sc:name ?objName.
}
LIMIT 50

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P2522'), ('pName', 'victory'), ('obj', 'http://www.wikidata.org/entity/Q1426'), ('objName', 'Roger Federer')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q289587'), ('objName', '2012 Wimbledon Championships')]
# 2

# %%
## Return the four Grand Slam of tennis (hint: One of these four is Wimbledon) (the result set must be a list of four couples Grand Slam IRI and label).

# Q1426 = Roger Federer -> P2522 = victory
    # Q782589 = 2010 Australian Open – Men's Singles
    # Q753300 = 2012 Wimbledon Championships
    # Q304072 = 2008 US Open – Men's Singles
    # Q741573 = 2009 French Open – Men's Singles
    
# Q289587 = '2012 Wimbledon Championships'
# trying to exprole backward from Q289587 = '2012 Wimbledon Championships'
    
queryString = """
SELECT ?p ?pName ?obj ?objName
WHERE {
   # BACKWARD DISCOVERY
   # ?obj ?p wd:Q289587 .
   # get the label
   # ?p sc:name ?pName.
   # ?obj sc:name ?objName.
}
LIMIT 50

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P361'), ('pName', 'part of'), ('obj', 'http://www.wikidata.org/entity/Q15854764'), ('objName', "2012 Wimbledon Championships – Ladies' Invitation Doubles")]
# [('p', 'http://www.wikidata.org/prop/direct/P361'), ('pName', 'part of'), ('obj', 'http://www.wikidata.org/entity/Q842282'), ('objName', "2012 Wimbledon Championships – Women's Singles")]
# [('p', 'http://www.wikidata.org/prop/direct/P361'), ('pName', 'part of'), ('obj', 'http://www.wikidata.org/entity/Q1064519'), ('objName', "2012 Wimbledon Championships – Men's Doubles")]
# [('p', 'http://www.wikidata.org/prop/direct/P361'), ('pName', 'part of'), ('obj', 'http://www.wikidata.org/entity/Q1077803'), ('objName', "2012 Wimbledon Championships – Women's Doubles")]
# [('p', 'http://www.wikidata.org/prop/direct/P156'), ('pName', 'followed by'), ('obj', 'http://www.wikidata.org/entity/Q245073'), ('objName', '2011 Wimbledon Championships')]
# [('p', 'http://www.wikidata.org/prop/direct/P361'), ('pName', 'part of'), ('obj', 'http://www.wikidata.org/entity/Q524340'), ('objName', '2012 Wimbledon Championships – Mixed Doubles')]
# [('p', 'http://www.wikidata.org/prop/direct/P155'), ('pName', 'follows'), ('obj', 'http://www.wikidata.org/entity/Q559726'), ('objName', '2013 Wimbledon Championships')]
# [('p', 'http://www.wikidata.org/prop/direct/P361'), ('pName', 'part of'), ('obj', 'http://www.wikidata.org/entity/Q753300'), ('objName', "2012 Wimbledon Championships – Gentlemen's Singles")]
# [('p', 'http://www.wikidata.org/prop/direct/P301'), ('pName', "category's main topic"), ('obj', 'http://www.wikidata.org/entity/Q8201949'), ('objName', 'Category:2012 Wimbledon Championships')]
# [('p', 'http://www.wikidata.org/prop/direct/P361'), ('pName', 'part of'), ('obj', 'http://www.wikidata.org/entity/Q3994924'), ('objName', "2012 Wimbledon Championships – Senior Gentlemen's Invitation Doubles")]
# [('p', 'http://www.wikidata.org/prop/direct/P361'), ('pName', 'part of'), ('obj', 'http://www.wikidata.org/entity/Q2074998'), ('objName', "2012 Wimbledon Championships – Boys' Singles")]
# [('p', 'http://www.wikidata.org/prop/direct/P361'), ('pName', 'part of'), ('obj', 'http://www.wikidata.org/entity/Q3994920'), ('objName', "2012 Wimbledon Championships – Wheelchair Women's Doubles")]
# [('p', 'http://www.wikidata.org/prop/direct/P361'), ('pName', 'part of'), ('obj', 'http://www.wikidata.org/entity/Q3994926'), ('objName', "2012 Wimbledon Championships – Men's Doubles Qualifying")]
# [('p', 'http://www.wikidata.org/prop/direct/P361'), ('pName', 'part of'), ('obj', 'http://www.wikidata.org/entity/Q3994922'), ('objName', "2012 Wimbledon Championships – Wheelchair Men's Doubles")]
# [('p', 'http://www.wikidata.org/prop/direct/P361'), ('pName', 'part of'), ('obj', 'http://www.wikidata.org/entity/Q2073770'), ('objName', "2012 Wimbledon Championships – Women's Singles Qualifying")]
# [('p', 'http://www.wikidata.org/prop/direct/P361'), ('pName', 'part of'), ('obj', 'http://www.wikidata.org/entity/Q2620248'), ('objName', "2012 Wimbledon Championships – Girls' Singles")]
# [('p', 'http://www.wikidata.org/prop/direct/P361'), ('pName', 'part of'), ('obj', 'http://www.wikidata.org/entity/Q3994925'), ('objName', "2012 Wimbledon Championships – Women's Doubles Qualifying")]
# [('p', 'http://www.wikidata.org/prop/direct/P361'), ('pName', 'part of'), ('obj', 'http://www.wikidata.org/entity/Q3994923'), ('objName', "2012 Wimbledon Championships – Gentlemen's Invitation Doubles")]
# [('p', 'http://www.wikidata.org/prop/direct/P361'), ('pName', 'part of'), ('obj', 'http://www.wikidata.org/entity/Q3994928'), ('objName', "2012 Wimbledon Championships – Boys' Doubles")]
# [('p', 'http://www.wikidata.org/prop/direct/P361'), ('pName', 'part of'), ('obj', 'http://www.wikidata.org/entity/Q2074677'), ('objName', "2012 Wimbledon Championships – Girls' Doubles")]
# [('p', 'http://www.wikidata.org/prop/direct/P1269'), ('pName', 'facet of'), ('obj', 'http://www.wikidata.org/entity/Q16155022'), ('objName', "2012 Wimbledon Championships – Men's Singles final")]
# [('p', 'http://www.wikidata.org/prop/direct/P361'), ('pName', 'part of'), ('obj', 'http://www.wikidata.org/entity/Q2759253'), ('objName', "2012 Wimbledon Championships – Men's Singles Qualifying")]
# 22

# %%
## Return the four Grand Slam of tennis (hint: One of these four is Wimbledon) (the result set must be a list of four couples Grand Slam IRI and label).

# Q1426 = Roger Federer -> P2522 = victory
    # Q782589 = 2010 Australian Open – Men's Singles
    # Q753300 = 2012 Wimbledon Championships
    # Q304072 = 2008 US Open – Men's Singles
    # Q741573 = 2009 French Open – Men's Singles
    
# Q289587 = '2012 Wimbledon Championships'
# trying to exprole forward from Q289587 = '2012 Wimbledon Championships'
    
queryString = """
SELECT ?p ?pName ?obj ?objName
WHERE {
   # FORWARD DISCOVERY
   wd:Q289587 ?p ?obj .
   # get the label
   # ?p sc:name ?pName.
   # ?obj sc:name ?objName.
}
LIMIT 50

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P17'), ('pName', 'country'), ('obj', 'http://www.wikidata.org/entity/Q145'), ('objName', 'United Kingdom')]
# [('p', 'http://www.wikidata.org/prop/direct/P641'), ('pName', 'sport'), ('obj', 'http://www.wikidata.org/entity/Q847'), ('objName', 'tennis')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q47345468'), ('objName', 'tennis tournament edition')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q842282'), ('objName', "2012 Wimbledon Championships – Women's Singles")]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q1064519'), ('objName', "2012 Wimbledon Championships – Men's Doubles")]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q1077803'), ('objName', "2012 Wimbledon Championships – Women's Doubles")]
# [('p', 'http://www.wikidata.org/prop/direct/P155'), ('pName', 'follows'), ('obj', 'http://www.wikidata.org/entity/Q245073'), ('objName', '2011 Wimbledon Championships')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q41520'), ('objName', 'Wimbledon Championships')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q524340'), ('objName', '2012 Wimbledon Championships – Mixed Doubles')]
# [('p', 'http://www.wikidata.org/prop/direct/P156'), ('pName', 'followed by'), ('obj', 'http://www.wikidata.org/entity/Q559726'), ('objName', '2013 Wimbledon Championships')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q753300'), ('objName', "2012 Wimbledon Championships – Gentlemen's Singles")]
# [('p', 'http://www.wikidata.org/prop/direct/P910'), ('pName', "topic's main category"), ('obj', 'http://www.wikidata.org/entity/Q8201949'), ('objName', 'Category:2012 Wimbledon Championships')]
# 12

# %%
## Return the four Grand Slam of tennis (hint: One of these four is Wimbledon) (the result set must be a list of four couples Grand Slam IRI and label).

# Q1426 = Roger Federer -> P2522 = victory
    # Q782589 = 2010 Australian Open – Men's Singles
    # Q753300 = 2012 Wimbledon Championships
    # Q304072 = 2008 US Open – Men's Singles
    # Q741573 = 2009 French Open – Men's Singles
             
# Q289587 = '2012 Wimbledon Championships'
# Q41520 = Wimbledon Championships
    
# trying to exprole from Q41520 = Wimbledon Championships
    
queryString = """
SELECT ?p ?pName ?obj ?objName
WHERE {
   # FORWARD DISCOVERY
   wd:Q41520 ?p ?obj .
   # get the label
   # ?p sc:name ?pName.
   # ?obj sc:name ?objName.
}
LIMIT 50

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P664'), ('pName', 'organizer'), ('obj', 'http://www.wikidata.org/entity/Q815369'), ('objName', 'All England Lawn Tennis and Croquet Club')]
# [('p', 'http://www.wikidata.org/prop/direct/P276'), ('pName', 'location'), ('obj', 'http://www.wikidata.org/entity/Q815369'), ('objName', 'All England Lawn Tennis and Croquet Club')]
# [('p', 'http://www.wikidata.org/prop/direct/P664'), ('pName', 'organizer'), ('obj', 'http://www.wikidata.org/entity/Q223041'), ('objName', 'International Tennis Federation')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('obj', 'http://www.wikidata.org/entity/Q13219666'), ('objName', 'tennis tournament')]
# [('p', 'http://www.wikidata.org/prop/direct/P17'), ('pName', 'country'), ('obj', 'http://www.wikidata.org/entity/Q145'), ('objName', 'United Kingdom')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q18608583'), ('objName', 'recurring sporting event')]
# [('p', 'http://www.wikidata.org/prop/direct/P641'), ('pName', 'sport'), ('obj', 'http://www.wikidata.org/entity/Q847'), ('objName', 'tennis')]
# [('p', 'http://www.wikidata.org/prop/direct/P765'), ('pName', 'surface played on'), ('obj', 'http://www.wikidata.org/entity/Q1151291'), ('objName', 'grass court')]
# [('p', 'http://www.wikidata.org/prop/direct/P7959'), ('pName', 'historic county'), ('obj', 'http://www.wikidata.org/entity/Q67443130'), ('objName', 'Surrey')]
# [('p', 'http://www.wikidata.org/prop/direct/P361'), ('pName', 'part of'), ('obj', 'http://www.wikidata.org/entity/Q102113'), ('objName', 'Grand Slam of tennis')]
# [('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('obj', 'http://www.wikidata.org/entity/Q736742'), ('objName', 'Wimbledon')]
# [('p', 'http://www.wikidata.org/prop/direct/P664'), ('pName', 'organizer'), ('obj', 'http://www.wikidata.org/entity/Q1337913'), ('objName', 'Lawn Tennis Association')]
# [('p', 'http://www.wikidata.org/prop/direct/P2354'), ('pName', 'has list'), ('obj', 'http://www.wikidata.org/entity/Q6585893'), ('objName', 'list of Wimbledon singles finalists during the open era')]
# [('p', 'http://www.wikidata.org/prop/direct/P1687'), ('pName', 'Wikidata property'), ('obj', 'http://www.wikidata.org/entity/P4503'), ('objName', 'Wimbledon player ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1424'), ('pName', "topic's main template"), ('obj', 'http://www.wikidata.org/entity/Q43323825'), ('objName', 'Template:Wimbledon player')]
# [('p', 'http://www.wikidata.org/prop/direct/P1889'), ('pName', 'different from'), ('obj', 'http://www.wikidata.org/entity/Q206375'), ('objName', 'Wimbledon')]
# [('p', 'http://www.wikidata.org/prop/direct/P910'), ('pName', "topic's main category"), ('obj', 'http://www.wikidata.org/entity/Q5326534'), ('objName', 'Category:The Championships, Wimbledon')]
# [('p', 'http://www.wikidata.org/prop/direct/P4622'), ('pName', 'trophy awarded'), ('obj', 'http://www.wikidata.org/entity/Q7920608'), ('objName', 'Venus Rosewater Dish')]
# 18

# %%
## Return the four Grand Slam of tennis (hint: One of these four is Wimbledon) (the result set must be a list of four couples Grand Slam IRI and label).

# Q1426 = Roger Federer -> P2522 = victory
    # Q782589 = 2010 Australian Open – Men's Singles
    # Q753300 = 2012 Wimbledon Championships
    # Q304072 = 2008 US Open – Men's Singles
    # Q741573 = 2009 French Open – Men's Singles
             
# Q289587 = '2012 Wimbledon Championships'
     
# Q41520 = Wimbledon Championships -> P361 (part of) Q102113 Grand Slam of tennis

# trying to exprole from Q102113 =  Grand Slam of tennis
    
queryString = """
SELECT ?p ?pName ?obj ?objName
WHERE {
   # FORWARD DISCOVERY
   wd:Q102113 ?p ?obj .
   # get the label
   # ?p sc:name ?pName.
   # ?obj sc:name ?objName.
}
LIMIT 50

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q50301185'), ('objName', 'tennis tour with multiple editions')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('obj', 'http://www.wikidata.org/entity/Q7700500'), ('objName', 'tennis tour')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q2223649'), ('objName', 'French cheese')]
# [('p', 'http://www.wikidata.org/prop/direct/P1424'), ('pName', "topic's main template"), ('obj', 'http://www.wikidata.org/entity/Q5851433'), ('objName', 'Template:Infobox GrandSlamTournaments')]
# [('p', 'http://www.wikidata.org/prop/direct/P641'), ('pName', 'sport'), ('obj', 'http://www.wikidata.org/entity/Q847'), ('objName', 'tennis')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q123577'), ('objName', 'US Open')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q41520'), ('objName', 'Wimbledon Championships')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q60874'), ('objName', 'Australian Open')]
# [('p', 'http://www.wikidata.org/prop/direct/P2354'), ('pName', 'has list'), ('obj', 'http://www.wikidata.org/entity/Q1426439'), ('objName', "list of Grand Slam men's singles champions")]
# [('p', 'http://www.wikidata.org/prop/direct/P910'), ('pName', "topic's main category"), ('obj', 'http://www.wikidata.org/entity/Q18156144'), ('objName', 'Category:Grand Slam (tennis)')]
# [('p', 'http://www.wikidata.org/prop/direct/P2354'), ('pName', 'has list'), ('obj', 'http://www.wikidata.org/entity/Q645455'), ('objName', "list of Grand Slam women's singles champions")]
# 11

# %%
## Return the four Grand Slam of tennis (hint: One of these four is Wimbledon) (the result set must be a list of four couples Grand Slam IRI and label).

# Q1426 = Roger Federer -> P2522 = victory
    # Q782589 = 2010 Australian Open – Men's Singles
    # Q753300 = 2012 Wimbledon Championships
    # Q304072 = 2008 US Open – Men's Singles
    # Q741573 = 2009 French Open – Men's Singles
             
# Q289587 = '2012 Wimbledon Championships'
     
# Q41520 = Wimbledon Championships -> P361 (part of) Q102113 Grand Slam of tennis

# Found from Q102113 =  Grand Slam of tennis through wdt:P527 'has part'
queryString = """
SELECT DISTINCT ?obj ?objName
WHERE {
   # FORWARD DISCOVERY
   wd:Q102113 wdt:P527 ?obj .
   # get the label
   # ?obj sc:name ?objName.
}
LIMIT 50

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('obj', 'http://www.wikidata.org/entity/Q2223649'), ('objName', 'French cheese')]
# [('obj', 'http://www.wikidata.org/entity/Q123577'), ('objName', 'US Open')]
# [('obj', 'http://www.wikidata.org/entity/Q41520'), ('objName', 'Wimbledon Championships')]
# [('obj', 'http://www.wikidata.org/entity/Q60874'), ('objName', 'Australian Open')]
# 4

# %%
# WORKING BUT WITH French Cheese instead of French Open

# %%
## Return the four Grand Slam of tennis (hint: One of these four is Wimbledon) (the result set must be a list of four couples Grand Slam IRI and label).

# Q1426 = Roger Federer -> P2522 = victory
    # Q782589 = 2010 Australian Open – Men's Singles
    # Q753300 = 2012 Wimbledon Championships
    # Q304072 = 2008 US Open – Men's Singles
    # Q741573 = 2009 French Open – Men's Singles
             
# Q289587 = '2012 Wimbledon Championships'
     
# Q41520 = Wimbledon Championships -> P361 (part of) Q102113 Grand Slam of tennis
# WORKING BUT WITH French Cheese instead of French Open so lets re-try
# to exprole from Q741573 = 2009 French Open – Men's Singles 
# and check if It's a typo

queryString = """
SELECT DISTINCT ?p ?pName ?obj ?objName
WHERE {
   # FORWARD DISCOVERY
   wd:Q741573 ?p ?obj .
   # get the label
   # ?p sc:name ?pName .
   # ?obj sc:name ?objName.
}
LIMIT 50

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P361'), ('pName', 'part of'), ('obj', 'http://www.wikidata.org/entity/Q381118'), ('objName', '2009 French Open')]
# [('p', 'http://www.wikidata.org/prop/direct/P17'), ('pName', 'country'), ('obj', 'http://www.wikidata.org/entity/Q142'), ('objName', 'France')]
# [('p', 'http://www.wikidata.org/prop/direct/P641'), ('pName', 'sport'), ('obj', 'http://www.wikidata.org/entity/Q847'), ('objName', 'tennis')]
# [('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner'), ('obj', 'http://www.wikidata.org/entity/Q1426'), ('objName', 'Roger Federer')]
# [('p', 'http://www.wikidata.org/prop/direct/P2094'), ('pName', 'competition class'), ('obj', 'http://www.wikidata.org/entity/Q16893072'), ('objName', "men's singles")]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q46190676'), ('objName', 'tennis event')]
# 6

# %%
## Return the four Grand Slam of tennis (hint: One of these four is Wimbledon) (the result set must be a list of four couples Grand Slam IRI and label).

# Q1426 = Roger Federer -> P2522 = victory
    # Q782589 = 2010 Australian Open – Men's Singles
    # Q753300 = 2012 Wimbledon Championships
    # Q304072 = 2008 US Open – Men's Singles
    # Q741573 = 2009 French Open – Men's Singles
             
# Q289587 = '2012 Wimbledon Championships'
     
# Q41520 = Wimbledon Championships -> P361 (part of) Q102113 Grand Slam of tennis

# Q381118 = '2009 French Open'
# trying to re-explore as done with Wimbledon Championship

queryString = """
SELECT DISTINCT ?p ?pName ?obj ?objName
WHERE {
   # FORWARD DISCOVERY
   wd:Q381118 ?p ?obj .
   # get the label
   # ?p sc:name ?pName .
   # ?obj sc:name ?objName.
}
LIMIT 50

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P155'), ('pName', 'follows'), ('obj', 'http://www.wikidata.org/entity/Q277655'), ('objName', '2008 French Open')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q1752825'), ('objName', "2009 French Open – Girls' Doubles")]
# [('p', 'http://www.wikidata.org/prop/direct/P156'), ('pName', 'followed by'), ('obj', 'http://www.wikidata.org/entity/Q248438'), ('objName', '2010 French Open')]
# [('p', 'http://www.wikidata.org/prop/direct/P17'), ('pName', 'country'), ('obj', 'http://www.wikidata.org/entity/Q142'), ('objName', 'France')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q43605'), ('objName', 'French Open')]
# [('p', 'http://www.wikidata.org/prop/direct/P641'), ('pName', 'sport'), ('obj', 'http://www.wikidata.org/entity/Q847'), ('objName', 'tennis')]
# [('p', 'http://www.wikidata.org/prop/direct/P2094'), ('pName', 'competition class'), ('obj', 'http://www.wikidata.org/entity/Q920057'), ('objName', "women's sports")]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q909464'), ('objName', "2009 French Open – Women's Doubles")]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q47345468'), ('objName', 'tennis tournament edition')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q741573'), ('objName', "2009 French Open – Men's Singles")]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q201269'), ('objName', "2009 French Open – Women's Singles")]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q2615231'), ('objName', "2009 French Open – Girls' Singles")]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q672960'), ('objName', "2009 French Open – Men's Doubles")]
# [('p', 'http://www.wikidata.org/prop/direct/P910'), ('pName', "topic's main category"), ('obj', 'http://www.wikidata.org/entity/Q8196111'), ('objName', 'Category:2009 French Open')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q923580'), ('objName', '2009 French Open – Mixed Doubles')]
# 15

# %%
## Return the four Grand Slam of tennis (hint: One of these four is Wimbledon) (the result set must be a list of four couples Grand Slam IRI and label).

# Q1426 = Roger Federer -> P2522 = victory
    # Q782589 = 2010 Australian Open – Men's Singles
    # Q753300 = 2012 Wimbledon Championships
    # Q304072 = 2008 US Open – Men's Singles
    # Q741573 = 2009 French Open – Men's Singles
             
# Q289587 = '2012 Wimbledon Championships'
     
# Q41520 = Wimbledon Championships -> P361 (part of) Q102113 Grand Slam of tennis

# Q381118 = '2009 French Open' -> P31 -> Q43605 'French Open'

# It's not a typo so I lets find another way to get to this node

queryString = """
SELECT DISTINCT ?p ?pName ?obj ?objName
WHERE {
   # FORWARD DISCOVERY
   wd:Q43605 ?p ?obj .
   # get the label
   # ?p sc:name ?pName .
   # ?obj sc:name ?objName.
}
LIMIT 50

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P276'), ('pName', 'location'), ('obj', 'http://www.wikidata.org/entity/Q1613027'), ('objName', 'Stade Roland-Garros')]
# [('p', 'http://www.wikidata.org/prop/direct/P765'), ('pName', 'surface played on'), ('obj', 'http://www.wikidata.org/entity/Q198718'), ('objName', 'clay court')]
# [('p', 'http://www.wikidata.org/prop/direct/P664'), ('pName', 'organizer'), ('obj', 'http://www.wikidata.org/entity/Q223041'), ('objName', 'International Tennis Federation')]
# [('p', 'http://www.wikidata.org/prop/direct/P4794'), ('pName', 'season starts'), ('obj', 'http://www.wikidata.org/entity/Q119'), ('objName', 'May')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('obj', 'http://www.wikidata.org/entity/Q13219666'), ('objName', 'tennis tournament')]
# [('p', 'http://www.wikidata.org/prop/direct/P17'), ('pName', 'country'), ('obj', 'http://www.wikidata.org/entity/Q142'), ('objName', 'France')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q18608583'), ('objName', 'recurring sporting event')]
# [('p', 'http://www.wikidata.org/prop/direct/P641'), ('pName', 'sport'), ('obj', 'http://www.wikidata.org/entity/Q847'), ('objName', 'tennis')]
# [('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('obj', 'http://www.wikidata.org/entity/Q90'), ('objName', 'Paris')]
# [('p', 'http://www.wikidata.org/prop/direct/P361'), ('pName', 'part of'), ('obj', 'http://www.wikidata.org/entity/Q102113'), ('objName', 'Grand Slam of tennis')]
# [('p', 'http://www.wikidata.org/prop/direct/P664'), ('pName', 'organizer'), ('obj', 'http://www.wikidata.org/entity/Q1349946'), ('objName', 'Fédération Française de Tennis')]
# [('p', 'http://www.wikidata.org/prop/direct/P910'), ('pName', "topic's main category"), ('obj', 'http://www.wikidata.org/entity/Q5326537'), ('objName', 'Category:French Open')]
# [('p', 'http://www.wikidata.org/prop/direct/P1889'), ('pName', 'different from'), ('obj', 'http://www.wikidata.org/entity/Q7829347'), ('objName', 'Tournoi de France')]
# [('p', 'http://www.wikidata.org/prop/direct/P138'), ('pName', 'named after'), ('obj', 'http://www.wikidata.org/entity/Q207709'), ('objName', 'Roland Garros')]
# 14

# %%
## Return the four Grand Slam of tennis (hint: One of these four is Wimbledon) (the result set must be a list of four couples Grand Slam IRI and label).

# Q1426 = Roger Federer -> P2522 = victory
    # Q782589 = 2010 Australian Open – Men's Singles
    # Q753300 = 2012 Wimbledon Championships
    # Q304072 = 2008 US Open – Men's Singles
    # Q741573 = 2009 French Open – Men's Singles
             
# Q289587 = '2012 Wimbledon Championships'
# Q41520 = Wimbledon Championships -> P361 (part of) Q102113 Grand Slam of tennis
# Q381118 = '2009 French Open' -> P31 -> Q43605 'French Open'

# It's not a typo so I lets find another way to get to this node
# going to same point from where I have started Q102113
    
queryString = """
SELECT DISTINCT ?p ?pName ?obj ?objName
WHERE {
   # FORWARD DISCOVERY
   wd:Q102113 ?p ?obj .
   # get the label
   # ?p sc:name ?pName .
   # ?obj sc:name ?objName.
}
LIMIT 50

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj', 'http://www.wikidata.org/entity/Q50301185'), ('objName', 'tennis tour with multiple editions')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('obj', 'http://www.wikidata.org/entity/Q7700500'), ('objName', 'tennis tour')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q2223649'), ('objName', 'French cheese')]
# [('p', 'http://www.wikidata.org/prop/direct/P1424'), ('pName', "topic's main template"), ('obj', 'http://www.wikidata.org/entity/Q5851433'), ('objName', 'Template:Infobox GrandSlamTournaments')]
# [('p', 'http://www.wikidata.org/prop/direct/P641'), ('pName', 'sport'), ('obj', 'http://www.wikidata.org/entity/Q847'), ('objName', 'tennis')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q123577'), ('objName', 'US Open')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q41520'), ('objName', 'Wimbledon Championships')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('obj', 'http://www.wikidata.org/entity/Q60874'), ('objName', 'Australian Open')]
# [('p', 'http://www.wikidata.org/prop/direct/P2354'), ('pName', 'has list'), ('obj', 'http://www.wikidata.org/entity/Q1426439'), ('objName', "list of Grand Slam men's singles champions")]
# [('p', 'http://www.wikidata.org/prop/direct/P910'), ('pName', "topic's main category"), ('obj', 'http://www.wikidata.org/entity/Q18156144'), ('objName', 'Category:Grand Slam (tennis)')]
# [('p', 'http://www.wikidata.org/prop/direct/P2354'), ('pName', 'has list'), ('obj', 'http://www.wikidata.org/entity/Q645455'), ('objName', "list of Grand Slam women's singles champions")]
# 11

# %%
## Return the four Grand Slam of tennis (hint: One of these four is Wimbledon) (the result set must be a list of four couples Grand Slam IRI and label).

# Q1426 = Roger Federer -> P2522 = victory
    # Q782589 = 2010 Australian Open – Men's Singles
    # Q753300 = 2012 Wimbledon Championships
    # Q304072 = 2008 US Open – Men's Singles
    # Q741573 = 2009 French Open – Men's Singles
             
# Q289587 = '2012 Wimbledon Championships'
# Q41520 = Wimbledon Championships -> P361 (part of) Q102113 Grand Slam of tennis
# Q381118 = '2009 French Open' -> P31 -> Q43605 'French Open'

# It's not a typo so I lets find another way to get to this node
# going to same point from where I have started Q102113
# with backward search
    
queryString = """
SELECT DISTINCT ?p ?pName ?obj ?objName
WHERE {
   # BACKWARD DISCOVERY
   # ?obj ?p wd:Q102113 .
   # get the label
   # ?p sc:name ?pName .
   # ?obj sc:name ?objName.
}
LIMIT 50

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P2522'), ('pName', 'victory'), ('obj', 'http://www.wikidata.org/entity/Q105868'), ('objName', 'Gabriela Sabatini')]
# [('p', 'http://www.wikidata.org/prop/direct/P1423'), ('pName', 'template has topic'), ('obj', 'http://www.wikidata.org/entity/Q5851433'), ('objName', 'Template:Infobox GrandSlamTournaments')]
# [('p', 'http://www.wikidata.org/prop/direct/P361'), ('pName', 'part of'), ('obj', 'http://www.wikidata.org/entity/Q43605'), ('objName', 'French Open')]
# [('p', 'http://www.wikidata.org/prop/direct/P2522'), ('pName', 'victory'), ('obj', 'http://www.wikidata.org/entity/Q105838'), ('objName', 'Marion Bartoli')]
# [('p', 'http://www.wikidata.org/prop/direct/P361'), ('pName', 'part of'), ('obj', 'http://www.wikidata.org/entity/Q123577'), ('objName', 'US Open')]
# [('p', 'http://www.wikidata.org/prop/direct/P361'), ('pName', 'part of'), ('obj', 'http://www.wikidata.org/entity/Q41520'), ('objName', 'Wimbledon Championships')]
# [('p', 'http://www.wikidata.org/prop/direct/P361'), ('pName', 'part of'), ('obj', 'http://www.wikidata.org/entity/Q60874'), ('objName', 'Australian Open')]
# [('p', 'http://www.wikidata.org/prop/direct/P301'), ('pName', "category's main topic"), ('obj', 'http://www.wikidata.org/entity/Q18156144'), ('objName', 'Category:Grand Slam (tennis)')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('obj', 'http://www.wikidata.org/entity/Q11300305'), ('objName', 'Grand Slam')]
# [('p', 'http://www.wikidata.org/prop/direct/P971'), ('pName', 'category combines topics'), ('obj', 'http://www.wikidata.org/entity/Q5326520'), ('objName', 'Category:Grand Slam (tennis) tournaments')]
# [('p', 'http://www.wikidata.org/prop/direct/P971'), ('pName', 'category combines topics'), ('obj', 'http://www.wikidata.org/entity/Q8498724'), ('objName', 'Category:Grand Slam (tennis) tournaments navigational boxes')]
# 11

# %%
## Return the four Grand Slam of tennis (hint: One of these four is Wimbledon) (the result set must be a list of four couples Grand Slam IRI and label).

# Q1426 = Roger Federer -> P2522 = victory
    # Q782589 = 2010 Australian Open – Men's Singles
    # Q753300 = 2012 Wimbledon Championships
    # Q304072 = 2008 US Open – Men's Singles
    # Q741573 = 2009 French Open – Men's Singles
             
# Q289587 = '2012 Wimbledon Championships'
# Q41520 = Wimbledon Championships -> P361 (part of) Q102113 Grand Slam of tennis
# Q381118 = '2009 French Open' -> P31 -> Q43605 'French Open'

# Found with backward search from Q102113 Grand Slam of tennis with relation P361 'part of'
    
queryString = """
SELECT DISTINCT ?obj ?objName
WHERE {
   # BACKWARD DISCOVERY
   # ?obj wdt:P361 wd:Q102113 .
   # get the label
   # ?obj sc:name ?objName.
}
LIMIT 50

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('obj', 'http://www.wikidata.org/entity/Q43605'), ('objName', 'French Open')]
# [('obj', 'http://www.wikidata.org/entity/Q123577'), ('objName', 'US Open')]
# [('obj', 'http://www.wikidata.org/entity/Q41520'), ('objName', 'Wimbledon Championships')]
# [('obj', 'http://www.wikidata.org/entity/Q60874'), ('objName', 'Australian Open')]
# 4

# %% [markdown]
# ### Final query for this task

# %%
# write your final query
## Return the four Grand Slam of tennis (hint: One of these four is Wimbledon) (the result set must be a list of four couples Grand Slam IRI and label).

# Q1426 = Roger Federer -> P2522 = victory
    # Q782589 = 2010 Australian Open – Men's Singles
    # Q753300 = 2012 Wimbledon Championships
    # Q304072 = 2008 US Open – Men's Singles
    # Q741573 = 2009 French Open – Men's Singles
             
    # Q289587 = '2012 Wimbledon Championships'
    # Q41520 = Wimbledon Championships -> P361 (part of) Q102113 Grand Slam of tennis
    # Q381118 = '2009 French Open' -> P31 -> Q43605 'French Open'
    
# SOL:
    # Q1426 (Roger Federer) 
    #    --P2522 (victory)--> Q741573 '2009 French Open – Men's Singles'
    #    --P361 (part of)--> Q381118 '2009 French Open'  
    #    --P31 (instance of)--> Q43605 'French Open'
#SOL#    --P361 (part of) --> Q102113 'Grand Slam of tennis' <-- wdt:P361(part of)-- RESULT

# getting all objects that are part of  Q102113 'Grand Slam of tennis'
    
queryString = """
# Retrieving distinct BGP of events in Grand Slam of tennis
SELECT DISTINCT ?event ?eventName
WHERE {
   # getting all events that are part of Q102113 'Grand Slam of tennis'
   wd:Q102113 ^wdt:P361 ?event.
   # get the label
   # ?event sc:name ?eventName.
}
LIMIT 50

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('event', 'http://www.wikidata.org/entity/Q43605'), ('eventName', 'French Open')]
# [('event', 'http://www.wikidata.org/entity/Q123577'), ('eventName', 'US Open')]
# [('event', 'http://www.wikidata.org/entity/Q41520'), ('eventName', 'Wimbledon Championships')]
# [('event', 'http://www.wikidata.org/entity/Q60874'), ('eventName', 'Australian Open')]
# 4

# %% [markdown]
# ## Task 4
# Find the three different type of possible surfaces in a tennis court (the result set must be a list of three couples surface IRI and label).

# %%
##Find the three different type of possible surfaces in a tennis court (the result set must be a list of three couples surface IRI and label).

# Q1426 (Roger Federer) 
    #    --P2522 (victory)--> Q741573 '2009 French Open – Men's Singles'
    #    --P361 (part of)--> Q381118 '2009 French Open'  
    #    --P31 (instance of)--> Q43605 'French Open'
    #    --P361 (part of) --> Q102113 'Grand Slam of tennis' <-- wdt:P361(part of)-- RESULT

# prev TASK
queryString = """
SELECT DISTINCT ?obj ?objName
WHERE {
   # BACKWARD DISCOVERY
   # getting all objects that are part of  Q102113 'Grand Slam of tennis'
   wd:Q102113 ^wdt:P361 ?obj.
   # get the label
   # ?obj sc:name ?objName.
}
LIMIT 50

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('obj', 'http://www.wikidata.org/entity/Q43605'), ('objName', 'French Open')]
# [('obj', 'http://www.wikidata.org/entity/Q123577'), ('objName', 'US Open')]
# [('obj', 'http://www.wikidata.org/entity/Q41520'), ('objName', 'Wimbledon Championships')]
# [('obj', 'http://www.wikidata.org/entity/Q60874'), ('objName', 'Australian Open')]
# 4

# %%
##Find the three different type of possible surfaces in a tennis court (the result set must be a list of three couples surface IRI and label).

# Q1426 (Roger Federer) 
    #    --P2522 (victory)--> Q741573 '2009 French Open – Men's Singles'
    #    --P361 (part of)--> Q381118 '2009 French Open'  
    #    --P31 (instance of)--> Q43605 'French Open'
    #    --P361 (part of) --> Q102113 'Grand Slam of tennis' <-- wdt:P361(part of)-- RESULT

# trying to find if there is any node that represent court from Q102113 with 2 degrees of depth

queryString = """
SELECT DISTINCT ?obj ?objName ?p ?pName ?obj2 ?obj2Name
WHERE {
   # BACKWARD DISCOVERY
   wd:Q102113 ^wdt:P361 ?obj.
   # get the label
   # ?obj sc:name ?objName.
   # ?obj ?p ?obj2.
   
   # ?p sc:name ?pName. 
   # ?obj2 sc:name ?obj2Name.
}
LIMIT 50

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('obj', 'http://www.wikidata.org/entity/Q43605'), ('objName', 'French Open'), ('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('obj2', 'http://www.wikidata.org/entity/Q90'), ('obj2Name', 'Paris')]
# [('obj', 'http://www.wikidata.org/entity/Q41520'), ('objName', 'Wimbledon Championships'), ('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('obj2', 'http://www.wikidata.org/entity/Q736742'), ('obj2Name', 'Wimbledon')]
# [('obj', 'http://www.wikidata.org/entity/Q43605'), ('objName', 'French Open'), ('p', 'http://www.wikidata.org/prop/direct/P138'), ('pName', 'named after'), ('obj2', 'http://www.wikidata.org/entity/Q207709'), ('obj2Name', 'Roland Garros')]
# [('obj', 'http://www.wikidata.org/entity/Q41520'), ('objName', 'Wimbledon Championships'), ('p', 'http://www.wikidata.org/prop/direct/P1424'), ('pName', "topic's main template"), ('obj2', 'http://www.wikidata.org/entity/Q43323825'), ('obj2Name', 'Template:Wimbledon player')]
# [('obj', 'http://www.wikidata.org/entity/Q41520'), ('objName', 'Wimbledon Championships'), ('p', 'http://www.wikidata.org/prop/direct/P1687'), ('pName', 'Wikidata property'), ('obj2', 'http://www.wikidata.org/entity/P4503'), ('obj2Name', 'Wimbledon player ID')]
# [('obj', 'http://www.wikidata.org/entity/Q43605'), ('objName', 'French Open'), ('p', 'http://www.wikidata.org/prop/direct/P17'), ('pName', 'country'), ('obj2', 'http://www.wikidata.org/entity/Q142'), ('obj2Name', 'France')]
# [('obj', 'http://www.wikidata.org/entity/Q41520'), ('objName', 'Wimbledon Championships'), ('p', 'http://www.wikidata.org/prop/direct/P17'), ('pName', 'country'), ('obj2', 'http://www.wikidata.org/entity/Q145'), ('obj2Name', 'United Kingdom')]
# [('obj', 'http://www.wikidata.org/entity/Q123577'), ('objName', 'US Open'), ('p', 'http://www.wikidata.org/prop/direct/P17'), ('pName', 'country'), ('obj2', 'http://www.wikidata.org/entity/Q30'), ('obj2Name', 'United States of America')]
# [('obj', 'http://www.wikidata.org/entity/Q60874'), ('objName', 'Australian Open'), ('p', 'http://www.wikidata.org/prop/direct/P17'), ('pName', 'country'), ('obj2', 'http://www.wikidata.org/entity/Q408'), ('obj2Name', 'Australia')]
# [('obj', 'http://www.wikidata.org/entity/Q43605'), ('objName', 'French Open'), ('p', 'http://www.wikidata.org/prop/direct/P1889'), ('pName', 'different from'), ('obj2', 'http://www.wikidata.org/entity/Q7829347'), ('obj2Name', 'Tournoi de France')]
# [('obj', 'http://www.wikidata.org/entity/Q41520'), ('objName', 'Wimbledon Championships'), ('p', 'http://www.wikidata.org/prop/direct/P1889'), ('pName', 'different from'), ('obj2', 'http://www.wikidata.org/entity/Q206375'), ('obj2Name', 'Wimbledon')]
# [('obj', 'http://www.wikidata.org/entity/Q60874'), ('objName', 'Australian Open'), ('p', 'http://www.wikidata.org/prop/direct/P2354'), ('pName', 'has list'), ('obj2', 'http://www.wikidata.org/entity/Q6562732'), ('obj2Name', 'list of Australian Open singles finalists during the open era')]
# [('obj', 'http://www.wikidata.org/entity/Q41520'), ('objName', 'Wimbledon Championships'), ('p', 'http://www.wikidata.org/prop/direct/P2354'), ('pName', 'has list'), ('obj2', 'http://www.wikidata.org/entity/Q6585893'), ('obj2Name', 'list of Wimbledon singles finalists during the open era')]
# [('obj', 'http://www.wikidata.org/entity/Q123577'), ('objName', 'US Open'), ('p', 'http://www.wikidata.org/prop/direct/P2354'), ('pName', 'has list'), ('obj2', 'http://www.wikidata.org/entity/Q6585894'), ('obj2Name', 'list of US Open singles finalists during the open era')]
# [('obj', 'http://www.wikidata.org/entity/Q43605'), ('objName', 'French Open'), ('p', 'http://www.wikidata.org/prop/direct/P276'), ('pName', 'location'), ('obj2', 'http://www.wikidata.org/entity/Q1613027'), ('obj2Name', 'Stade Roland-Garros')]
# [('obj', 'http://www.wikidata.org/entity/Q41520'), ('objName', 'Wimbledon Championships'), ('p', 'http://www.wikidata.org/prop/direct/P276'), ('pName', 'location'), ('obj2', 'http://www.wikidata.org/entity/Q815369'), ('obj2Name', 'All England Lawn Tennis and Croquet Club')]
# [('obj', 'http://www.wikidata.org/entity/Q123577'), ('objName', 'US Open'), ('p', 'http://www.wikidata.org/prop/direct/P276'), ('pName', 'location'), ('obj2', 'http://www.wikidata.org/entity/Q1852081'), ('obj2Name', 'USTA Billie Jean King National Tennis Center')]
# [('obj', 'http://www.wikidata.org/entity/Q60874'), ('objName', 'Australian Open'), ('p', 'http://www.wikidata.org/prop/direct/P276'), ('pName', 'location'), ('obj2', 'http://www.wikidata.org/entity/Q2228393'), ('obj2Name', 'Melbourne Park')]
# [('obj', 'http://www.wikidata.org/entity/Q43605'), ('objName', 'French Open'), ('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('obj2', 'http://www.wikidata.org/entity/Q13219666'), ('obj2Name', 'tennis tournament')]
# [('obj', 'http://www.wikidata.org/entity/Q123577'), ('objName', 'US Open'), ('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('obj2', 'http://www.wikidata.org/entity/Q13219666'), ('obj2Name', 'tennis tournament')]
# [('obj', 'http://www.wikidata.org/entity/Q41520'), ('objName', 'Wimbledon Championships'), ('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('obj2', 'http://www.wikidata.org/entity/Q13219666'), ('obj2Name', 'tennis tournament')]
# [('obj', 'http://www.wikidata.org/entity/Q60874'), ('objName', 'Australian Open'), ('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('obj2', 'http://www.wikidata.org/entity/Q13219666'), ('obj2Name', 'tennis tournament')]
# [('obj', 'http://www.wikidata.org/entity/Q123577'), ('objName', 'US Open'), ('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('obj2', 'http://www.wikidata.org/entity/Q18608583'), ('obj2Name', 'recurring sporting event')]
# [('obj', 'http://www.wikidata.org/entity/Q123577'), ('objName', 'US Open'), ('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('obj2', 'http://www.wikidata.org/entity/Q3270632'), ('obj2Name', 'national championship')]
# [('obj', 'http://www.wikidata.org/entity/Q43605'), ('objName', 'French Open'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj2', 'http://www.wikidata.org/entity/Q18608583'), ('obj2Name', 'recurring sporting event')]
# [('obj', 'http://www.wikidata.org/entity/Q123577'), ('objName', 'US Open'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj2', 'http://www.wikidata.org/entity/Q18608583'), ('obj2Name', 'recurring sporting event')]
# [('obj', 'http://www.wikidata.org/entity/Q41520'), ('objName', 'Wimbledon Championships'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj2', 'http://www.wikidata.org/entity/Q18608583'), ('obj2Name', 'recurring sporting event')]
# [('obj', 'http://www.wikidata.org/entity/Q60874'), ('objName', 'Australian Open'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj2', 'http://www.wikidata.org/entity/Q18608583'), ('obj2Name', 'recurring sporting event')]
# [('obj', 'http://www.wikidata.org/entity/Q43605'), ('objName', 'French Open'), ('p', 'http://www.wikidata.org/prop/direct/P361'), ('pName', 'part of'), ('obj2', 'http://www.wikidata.org/entity/Q102113'), ('obj2Name', 'Grand Slam of tennis')]
# [('obj', 'http://www.wikidata.org/entity/Q123577'), ('objName', 'US Open'), ('p', 'http://www.wikidata.org/prop/direct/P361'), ('pName', 'part of'), ('obj2', 'http://www.wikidata.org/entity/Q102113'), ('obj2Name', 'Grand Slam of tennis')]
# [('obj', 'http://www.wikidata.org/entity/Q41520'), ('objName', 'Wimbledon Championships'), ('p', 'http://www.wikidata.org/prop/direct/P361'), ('pName', 'part of'), ('obj2', 'http://www.wikidata.org/entity/Q102113'), ('obj2Name', 'Grand Slam of tennis')]
# [('obj', 'http://www.wikidata.org/entity/Q60874'), ('objName', 'Australian Open'), ('p', 'http://www.wikidata.org/prop/direct/P361'), ('pName', 'part of'), ('obj2', 'http://www.wikidata.org/entity/Q102113'), ('obj2Name', 'Grand Slam of tennis')]
# [('obj', 'http://www.wikidata.org/entity/Q41520'), ('objName', 'Wimbledon Championships'), ('p', 'http://www.wikidata.org/prop/direct/P4622'), ('pName', 'trophy awarded'), ('obj2', 'http://www.wikidata.org/entity/Q7920608'), ('obj2Name', 'Venus Rosewater Dish')]
# [('obj', 'http://www.wikidata.org/entity/Q60874'), ('objName', 'Australian Open'), ('p', 'http://www.wikidata.org/prop/direct/P4794'), ('pName', 'season starts'), ('obj2', 'http://www.wikidata.org/entity/Q108'), ('obj2Name', 'January')]
# [('obj', 'http://www.wikidata.org/entity/Q43605'), ('objName', 'French Open'), ('p', 'http://www.wikidata.org/prop/direct/P4794'), ('pName', 'season starts'), ('obj2', 'http://www.wikidata.org/entity/Q119'), ('obj2Name', 'May')]
# [('obj', 'http://www.wikidata.org/entity/Q43605'), ('objName', 'French Open'), ('p', 'http://www.wikidata.org/prop/direct/P641'), ('pName', 'sport'), ('obj2', 'http://www.wikidata.org/entity/Q847'), ('obj2Name', 'tennis')]
# [('obj', 'http://www.wikidata.org/entity/Q123577'), ('objName', 'US Open'), ('p', 'http://www.wikidata.org/prop/direct/P641'), ('pName', 'sport'), ('obj2', 'http://www.wikidata.org/entity/Q847'), ('obj2Name', 'tennis')]
# [('obj', 'http://www.wikidata.org/entity/Q41520'), ('objName', 'Wimbledon Championships'), ('p', 'http://www.wikidata.org/prop/direct/P641'), ('pName', 'sport'), ('obj2', 'http://www.wikidata.org/entity/Q847'), ('obj2Name', 'tennis')]
# [('obj', 'http://www.wikidata.org/entity/Q60874'), ('objName', 'Australian Open'), ('p', 'http://www.wikidata.org/prop/direct/P641'), ('pName', 'sport'), ('obj2', 'http://www.wikidata.org/entity/Q847'), ('obj2Name', 'tennis')]
# [('obj', 'http://www.wikidata.org/entity/Q41520'), ('objName', 'Wimbledon Championships'), ('p', 'http://www.wikidata.org/prop/direct/P664'), ('pName', 'organizer'), ('obj2', 'http://www.wikidata.org/entity/Q815369'), ('obj2Name', 'All England Lawn Tennis and Croquet Club')]
# [('obj', 'http://www.wikidata.org/entity/Q123577'), ('objName', 'US Open'), ('p', 'http://www.wikidata.org/prop/direct/P664'), ('pName', 'organizer'), ('obj2', 'http://www.wikidata.org/entity/Q948442'), ('obj2Name', "Women's Tennis Association")]
# [('obj', 'http://www.wikidata.org/entity/Q60874'), ('objName', 'Australian Open'), ('p', 'http://www.wikidata.org/prop/direct/P664'), ('pName', 'organizer'), ('obj2', 'http://www.wikidata.org/entity/Q3494880'), ('obj2Name', 'Tennis Australia')]
# [('obj', 'http://www.wikidata.org/entity/Q43605'), ('objName', 'French Open'), ('p', 'http://www.wikidata.org/prop/direct/P664'), ('pName', 'organizer'), ('obj2', 'http://www.wikidata.org/entity/Q223041'), ('obj2Name', 'International Tennis Federation')]
# [('obj', 'http://www.wikidata.org/entity/Q123577'), ('objName', 'US Open'), ('p', 'http://www.wikidata.org/prop/direct/P664'), ('pName', 'organizer'), ('obj2', 'http://www.wikidata.org/entity/Q223041'), ('obj2Name', 'International Tennis Federation')]
# [('obj', 'http://www.wikidata.org/entity/Q41520'), ('objName', 'Wimbledon Championships'), ('p', 'http://www.wikidata.org/prop/direct/P664'), ('pName', 'organizer'), ('obj2', 'http://www.wikidata.org/entity/Q223041'), ('obj2Name', 'International Tennis Federation')]
# [('obj', 'http://www.wikidata.org/entity/Q60874'), ('objName', 'Australian Open'), ('p', 'http://www.wikidata.org/prop/direct/P664'), ('pName', 'organizer'), ('obj2', 'http://www.wikidata.org/entity/Q223041'), ('obj2Name', 'International Tennis Federation')]
# [('obj', 'http://www.wikidata.org/entity/Q123577'), ('objName', 'US Open'), ('p', 'http://www.wikidata.org/prop/direct/P664'), ('pName', 'organizer'), ('obj2', 'http://www.wikidata.org/entity/Q1156323'), ('obj2Name', 'United States Tennis Association')]
# [('obj', 'http://www.wikidata.org/entity/Q41520'), ('objName', 'Wimbledon Championships'), ('p', 'http://www.wikidata.org/prop/direct/P664'), ('pName', 'organizer'), ('obj2', 'http://www.wikidata.org/entity/Q1337913'), ('obj2Name', 'Lawn Tennis Association')]
# [('obj', 'http://www.wikidata.org/entity/Q43605'), ('objName', 'French Open'), ('p', 'http://www.wikidata.org/prop/direct/P664'), ('pName', 'organizer'), ('obj2', 'http://www.wikidata.org/entity/Q1349946'), ('obj2Name', 'Fédération Française de Tennis')]
# [('obj', 'http://www.wikidata.org/entity/Q43605'), ('objName', 'French Open'), ('p', 'http://www.wikidata.org/prop/direct/P765'), ('pName', 'surface played on'), ('obj2', 'http://www.wikidata.org/entity/Q198718'), ('obj2Name', 'clay court')]
# 50

# %%
##Find the three different type of possible surfaces in a tennis court (the result set must be a list of three couples surface IRI and label).

# Q1426 (Roger Federer) 
    #    --P2522 (victory)--> Q741573 '2009 French Open – Men's Singles'
    #    --P361 (part of)--> Q381118 '2009 French Open'  
    #    --P31 (instance of)--> Q43605 'French Open'
    #    --P361 (part of) --> Q102113 'Grand Slam of tennis' <-- wdt:P361(part of)-- RESULT

# trying to find if there is any node that represent court from Q102113 with 2 degrees of depth
# excluding P17 country
queryString = """
SELECT DISTINCT ?obj ?objName ?p ?pName ?obj2 ?obj2Name
WHERE {
   # BACKWARD DISCOVERY
   wd:Q102113 ^wdt:P361 ?obj.
   # get the label
   # ?obj sc:name ?objName.
   # ?obj ?p ?obj2.
   
   # ?p sc:name ?pName. 
   # ?obj2 sc:name ?obj2Name.
   
   # excluding country
   FILTER (?p != wdt:P17)
}
LIMIT 50

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('obj', 'http://www.wikidata.org/entity/Q43605'), ('objName', 'French Open'), ('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('obj2', 'http://www.wikidata.org/entity/Q90'), ('obj2Name', 'Paris')]
# [('obj', 'http://www.wikidata.org/entity/Q41520'), ('objName', 'Wimbledon Championships'), ('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('obj2', 'http://www.wikidata.org/entity/Q736742'), ('obj2Name', 'Wimbledon')]
# [('obj', 'http://www.wikidata.org/entity/Q43605'), ('objName', 'French Open'), ('p', 'http://www.wikidata.org/prop/direct/P138'), ('pName', 'named after'), ('obj2', 'http://www.wikidata.org/entity/Q207709'), ('obj2Name', 'Roland Garros')]
# [('obj', 'http://www.wikidata.org/entity/Q41520'), ('objName', 'Wimbledon Championships'), ('p', 'http://www.wikidata.org/prop/direct/P1424'), ('pName', "topic's main template"), ('obj2', 'http://www.wikidata.org/entity/Q43323825'), ('obj2Name', 'Template:Wimbledon player')]
# [('obj', 'http://www.wikidata.org/entity/Q41520'), ('objName', 'Wimbledon Championships'), ('p', 'http://www.wikidata.org/prop/direct/P1687'), ('pName', 'Wikidata property'), ('obj2', 'http://www.wikidata.org/entity/P4503'), ('obj2Name', 'Wimbledon player ID')]
# [('obj', 'http://www.wikidata.org/entity/Q43605'), ('objName', 'French Open'), ('p', 'http://www.wikidata.org/prop/direct/P1889'), ('pName', 'different from'), ('obj2', 'http://www.wikidata.org/entity/Q7829347'), ('obj2Name', 'Tournoi de France')]
# [('obj', 'http://www.wikidata.org/entity/Q41520'), ('objName', 'Wimbledon Championships'), ('p', 'http://www.wikidata.org/prop/direct/P1889'), ('pName', 'different from'), ('obj2', 'http://www.wikidata.org/entity/Q206375'), ('obj2Name', 'Wimbledon')]
# [('obj', 'http://www.wikidata.org/entity/Q60874'), ('objName', 'Australian Open'), ('p', 'http://www.wikidata.org/prop/direct/P2354'), ('pName', 'has list'), ('obj2', 'http://www.wikidata.org/entity/Q6562732'), ('obj2Name', 'list of Australian Open singles finalists during the open era')]
# [('obj', 'http://www.wikidata.org/entity/Q41520'), ('objName', 'Wimbledon Championships'), ('p', 'http://www.wikidata.org/prop/direct/P2354'), ('pName', 'has list'), ('obj2', 'http://www.wikidata.org/entity/Q6585893'), ('obj2Name', 'list of Wimbledon singles finalists during the open era')]
# [('obj', 'http://www.wikidata.org/entity/Q123577'), ('objName', 'US Open'), ('p', 'http://www.wikidata.org/prop/direct/P2354'), ('pName', 'has list'), ('obj2', 'http://www.wikidata.org/entity/Q6585894'), ('obj2Name', 'list of US Open singles finalists during the open era')]
# [('obj', 'http://www.wikidata.org/entity/Q43605'), ('objName', 'French Open'), ('p', 'http://www.wikidata.org/prop/direct/P276'), ('pName', 'location'), ('obj2', 'http://www.wikidata.org/entity/Q1613027'), ('obj2Name', 'Stade Roland-Garros')]
# [('obj', 'http://www.wikidata.org/entity/Q41520'), ('objName', 'Wimbledon Championships'), ('p', 'http://www.wikidata.org/prop/direct/P276'), ('pName', 'location'), ('obj2', 'http://www.wikidata.org/entity/Q815369'), ('obj2Name', 'All England Lawn Tennis and Croquet Club')]
# [('obj', 'http://www.wikidata.org/entity/Q123577'), ('objName', 'US Open'), ('p', 'http://www.wikidata.org/prop/direct/P276'), ('pName', 'location'), ('obj2', 'http://www.wikidata.org/entity/Q1852081'), ('obj2Name', 'USTA Billie Jean King National Tennis Center')]
# [('obj', 'http://www.wikidata.org/entity/Q60874'), ('objName', 'Australian Open'), ('p', 'http://www.wikidata.org/prop/direct/P276'), ('pName', 'location'), ('obj2', 'http://www.wikidata.org/entity/Q2228393'), ('obj2Name', 'Melbourne Park')]
# [('obj', 'http://www.wikidata.org/entity/Q43605'), ('objName', 'French Open'), ('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('obj2', 'http://www.wikidata.org/entity/Q13219666'), ('obj2Name', 'tennis tournament')]
# [('obj', 'http://www.wikidata.org/entity/Q123577'), ('objName', 'US Open'), ('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('obj2', 'http://www.wikidata.org/entity/Q13219666'), ('obj2Name', 'tennis tournament')]
# [('obj', 'http://www.wikidata.org/entity/Q41520'), ('objName', 'Wimbledon Championships'), ('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('obj2', 'http://www.wikidata.org/entity/Q13219666'), ('obj2Name', 'tennis tournament')]
# [('obj', 'http://www.wikidata.org/entity/Q60874'), ('objName', 'Australian Open'), ('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('obj2', 'http://www.wikidata.org/entity/Q13219666'), ('obj2Name', 'tennis tournament')]
# [('obj', 'http://www.wikidata.org/entity/Q123577'), ('objName', 'US Open'), ('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('obj2', 'http://www.wikidata.org/entity/Q18608583'), ('obj2Name', 'recurring sporting event')]
# [('obj', 'http://www.wikidata.org/entity/Q123577'), ('objName', 'US Open'), ('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('obj2', 'http://www.wikidata.org/entity/Q3270632'), ('obj2Name', 'national championship')]
# [('obj', 'http://www.wikidata.org/entity/Q43605'), ('objName', 'French Open'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj2', 'http://www.wikidata.org/entity/Q18608583'), ('obj2Name', 'recurring sporting event')]
# [('obj', 'http://www.wikidata.org/entity/Q123577'), ('objName', 'US Open'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj2', 'http://www.wikidata.org/entity/Q18608583'), ('obj2Name', 'recurring sporting event')]
# [('obj', 'http://www.wikidata.org/entity/Q41520'), ('objName', 'Wimbledon Championships'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj2', 'http://www.wikidata.org/entity/Q18608583'), ('obj2Name', 'recurring sporting event')]
# [('obj', 'http://www.wikidata.org/entity/Q60874'), ('objName', 'Australian Open'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj2', 'http://www.wikidata.org/entity/Q18608583'), ('obj2Name', 'recurring sporting event')]
# [('obj', 'http://www.wikidata.org/entity/Q43605'), ('objName', 'French Open'), ('p', 'http://www.wikidata.org/prop/direct/P361'), ('pName', 'part of'), ('obj2', 'http://www.wikidata.org/entity/Q102113'), ('obj2Name', 'Grand Slam of tennis')]
# [('obj', 'http://www.wikidata.org/entity/Q123577'), ('objName', 'US Open'), ('p', 'http://www.wikidata.org/prop/direct/P361'), ('pName', 'part of'), ('obj2', 'http://www.wikidata.org/entity/Q102113'), ('obj2Name', 'Grand Slam of tennis')]
# [('obj', 'http://www.wikidata.org/entity/Q41520'), ('objName', 'Wimbledon Championships'), ('p', 'http://www.wikidata.org/prop/direct/P361'), ('pName', 'part of'), ('obj2', 'http://www.wikidata.org/entity/Q102113'), ('obj2Name', 'Grand Slam of tennis')]
# [('obj', 'http://www.wikidata.org/entity/Q60874'), ('objName', 'Australian Open'), ('p', 'http://www.wikidata.org/prop/direct/P361'), ('pName', 'part of'), ('obj2', 'http://www.wikidata.org/entity/Q102113'), ('obj2Name', 'Grand Slam of tennis')]
# [('obj', 'http://www.wikidata.org/entity/Q41520'), ('objName', 'Wimbledon Championships'), ('p', 'http://www.wikidata.org/prop/direct/P4622'), ('pName', 'trophy awarded'), ('obj2', 'http://www.wikidata.org/entity/Q7920608'), ('obj2Name', 'Venus Rosewater Dish')]
# [('obj', 'http://www.wikidata.org/entity/Q60874'), ('objName', 'Australian Open'), ('p', 'http://www.wikidata.org/prop/direct/P4794'), ('pName', 'season starts'), ('obj2', 'http://www.wikidata.org/entity/Q108'), ('obj2Name', 'January')]
# [('obj', 'http://www.wikidata.org/entity/Q43605'), ('objName', 'French Open'), ('p', 'http://www.wikidata.org/prop/direct/P4794'), ('pName', 'season starts'), ('obj2', 'http://www.wikidata.org/entity/Q119'), ('obj2Name', 'May')]
# [('obj', 'http://www.wikidata.org/entity/Q43605'), ('objName', 'French Open'), ('p', 'http://www.wikidata.org/prop/direct/P641'), ('pName', 'sport'), ('obj2', 'http://www.wikidata.org/entity/Q847'), ('obj2Name', 'tennis')]
# [('obj', 'http://www.wikidata.org/entity/Q123577'), ('objName', 'US Open'), ('p', 'http://www.wikidata.org/prop/direct/P641'), ('pName', 'sport'), ('obj2', 'http://www.wikidata.org/entity/Q847'), ('obj2Name', 'tennis')]
# [('obj', 'http://www.wikidata.org/entity/Q41520'), ('objName', 'Wimbledon Championships'), ('p', 'http://www.wikidata.org/prop/direct/P641'), ('pName', 'sport'), ('obj2', 'http://www.wikidata.org/entity/Q847'), ('obj2Name', 'tennis')]
# [('obj', 'http://www.wikidata.org/entity/Q60874'), ('objName', 'Australian Open'), ('p', 'http://www.wikidata.org/prop/direct/P641'), ('pName', 'sport'), ('obj2', 'http://www.wikidata.org/entity/Q847'), ('obj2Name', 'tennis')]
# [('obj', 'http://www.wikidata.org/entity/Q41520'), ('objName', 'Wimbledon Championships'), ('p', 'http://www.wikidata.org/prop/direct/P664'), ('pName', 'organizer'), ('obj2', 'http://www.wikidata.org/entity/Q815369'), ('obj2Name', 'All England Lawn Tennis and Croquet Club')]
# [('obj', 'http://www.wikidata.org/entity/Q123577'), ('objName', 'US Open'), ('p', 'http://www.wikidata.org/prop/direct/P664'), ('pName', 'organizer'), ('obj2', 'http://www.wikidata.org/entity/Q948442'), ('obj2Name', "Women's Tennis Association")]
# [('obj', 'http://www.wikidata.org/entity/Q60874'), ('objName', 'Australian Open'), ('p', 'http://www.wikidata.org/prop/direct/P664'), ('pName', 'organizer'), ('obj2', 'http://www.wikidata.org/entity/Q3494880'), ('obj2Name', 'Tennis Australia')]
# [('obj', 'http://www.wikidata.org/entity/Q43605'), ('objName', 'French Open'), ('p', 'http://www.wikidata.org/prop/direct/P664'), ('pName', 'organizer'), ('obj2', 'http://www.wikidata.org/entity/Q223041'), ('obj2Name', 'International Tennis Federation')]
# [('obj', 'http://www.wikidata.org/entity/Q123577'), ('objName', 'US Open'), ('p', 'http://www.wikidata.org/prop/direct/P664'), ('pName', 'organizer'), ('obj2', 'http://www.wikidata.org/entity/Q223041'), ('obj2Name', 'International Tennis Federation')]
# [('obj', 'http://www.wikidata.org/entity/Q41520'), ('objName', 'Wimbledon Championships'), ('p', 'http://www.wikidata.org/prop/direct/P664'), ('pName', 'organizer'), ('obj2', 'http://www.wikidata.org/entity/Q223041'), ('obj2Name', 'International Tennis Federation')]
# [('obj', 'http://www.wikidata.org/entity/Q60874'), ('objName', 'Australian Open'), ('p', 'http://www.wikidata.org/prop/direct/P664'), ('pName', 'organizer'), ('obj2', 'http://www.wikidata.org/entity/Q223041'), ('obj2Name', 'International Tennis Federation')]
# [('obj', 'http://www.wikidata.org/entity/Q123577'), ('objName', 'US Open'), ('p', 'http://www.wikidata.org/prop/direct/P664'), ('pName', 'organizer'), ('obj2', 'http://www.wikidata.org/entity/Q1156323'), ('obj2Name', 'United States Tennis Association')]
# [('obj', 'http://www.wikidata.org/entity/Q41520'), ('objName', 'Wimbledon Championships'), ('p', 'http://www.wikidata.org/prop/direct/P664'), ('pName', 'organizer'), ('obj2', 'http://www.wikidata.org/entity/Q1337913'), ('obj2Name', 'Lawn Tennis Association')]
# [('obj', 'http://www.wikidata.org/entity/Q43605'), ('objName', 'French Open'), ('p', 'http://www.wikidata.org/prop/direct/P664'), ('pName', 'organizer'), ('obj2', 'http://www.wikidata.org/entity/Q1349946'), ('obj2Name', 'Fédération Française de Tennis')]
# [('obj', 'http://www.wikidata.org/entity/Q43605'), ('objName', 'French Open'), ('p', 'http://www.wikidata.org/prop/direct/P765'), ('pName', 'surface played on'), ('obj2', 'http://www.wikidata.org/entity/Q198718'), ('obj2Name', 'clay court')]
# [('obj', 'http://www.wikidata.org/entity/Q123577'), ('objName', 'US Open'), ('p', 'http://www.wikidata.org/prop/direct/P765'), ('pName', 'surface played on'), ('obj2', 'http://www.wikidata.org/entity/Q1330871'), ('obj2Name', 'hardcourt')]
# [('obj', 'http://www.wikidata.org/entity/Q60874'), ('objName', 'Australian Open'), ('p', 'http://www.wikidata.org/prop/direct/P765'), ('pName', 'surface played on'), ('obj2', 'http://www.wikidata.org/entity/Q1330871'), ('obj2Name', 'hardcourt')]
# [('obj', 'http://www.wikidata.org/entity/Q41520'), ('objName', 'Wimbledon Championships'), ('p', 'http://www.wikidata.org/prop/direct/P765'), ('pName', 'surface played on'), ('obj2', 'http://www.wikidata.org/entity/Q1151291'), ('obj2Name', 'grass court')]
# [('obj', 'http://www.wikidata.org/entity/Q60874'), ('objName', 'Australian Open'), ('p', 'http://www.wikidata.org/prop/direct/P765'), ('pName', 'surface played on'), ('obj2', 'http://www.wikidata.org/entity/Q1151291'), ('obj2Name', 'grass court')]
# 50

# %%
##Find the three different type of possible surfaces in a tennis court (the result set must be a list of three couples surface IRI and label).

# Q1426 (Roger Federer) 
    #    --P2522 (victory)--> Q741573 '2009 French Open – Men's Singles'
    #    --P361 (part of)--> Q381118 '2009 French Open'  
    #    --P31 (instance of)--> Q43605 'French Open'
    #    --P361 (part of) --> Q102113 'Grand Slam of tennis' <-- wdt:P361(part of)-- RESULT

# trying to find if there is any node that represent court from Q43605 with 2 degrees of depth
# excluding P17 country

queryString = """
SELECT DISTINCT ?p ?pName ?obj2 ?obj2Name
WHERE {
   # BACKWARD DISCOVERY
   # get the label
   wd:Q43605 ?p ?obj2.
   # ?p sc:name ?pName. 
   # ?obj2 sc:name ?obj2Name.
   
   FILTER (?p != wdt:P17)
}
LIMIT 50

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P276'), ('pName', 'location'), ('obj2', 'http://www.wikidata.org/entity/Q1613027'), ('obj2Name', 'Stade Roland-Garros')]
# [('p', 'http://www.wikidata.org/prop/direct/P765'), ('pName', 'surface played on'), ('obj2', 'http://www.wikidata.org/entity/Q198718'), ('obj2Name', 'clay court')]
# [('p', 'http://www.wikidata.org/prop/direct/P664'), ('pName', 'organizer'), ('obj2', 'http://www.wikidata.org/entity/Q223041'), ('obj2Name', 'International Tennis Federation')]
# [('p', 'http://www.wikidata.org/prop/direct/P4794'), ('pName', 'season starts'), ('obj2', 'http://www.wikidata.org/entity/Q119'), ('obj2Name', 'May')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('obj2', 'http://www.wikidata.org/entity/Q13219666'), ('obj2Name', 'tennis tournament')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('obj2', 'http://www.wikidata.org/entity/Q18608583'), ('obj2Name', 'recurring sporting event')]
# [('p', 'http://www.wikidata.org/prop/direct/P641'), ('pName', 'sport'), ('obj2', 'http://www.wikidata.org/entity/Q847'), ('obj2Name', 'tennis')]
# [('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('obj2', 'http://www.wikidata.org/entity/Q90'), ('obj2Name', 'Paris')]
# [('p', 'http://www.wikidata.org/prop/direct/P361'), ('pName', 'part of'), ('obj2', 'http://www.wikidata.org/entity/Q102113'), ('obj2Name', 'Grand Slam of tennis')]
# [('p', 'http://www.wikidata.org/prop/direct/P664'), ('pName', 'organizer'), ('obj2', 'http://www.wikidata.org/entity/Q1349946'), ('obj2Name', 'Fédération Française de Tennis')]
# [('p', 'http://www.wikidata.org/prop/direct/P910'), ('pName', "topic's main category"), ('obj2', 'http://www.wikidata.org/entity/Q5326537'), ('obj2Name', 'Category:French Open')]
# [('p', 'http://www.wikidata.org/prop/direct/P1889'), ('pName', 'different from'), ('obj2', 'http://www.wikidata.org/entity/Q7829347'), ('obj2Name', 'Tournoi de France')]
# [('p', 'http://www.wikidata.org/prop/direct/P138'), ('pName', 'named after'), ('obj2', 'http://www.wikidata.org/entity/Q207709'), ('obj2Name', 'Roland Garros')]
# 13

# %%
##Find the three different type of possible surfaces in a tennis court (the result set must be a list of three couples surface IRI and label).

# Q1426 (Roger Federer) 
    #    --P2522 (victory)--> Q741573 '2009 French Open – Men's Singles'
    #    --P361 (part of)--> Q381118 '2009 French Open'  
    #    --P31 (instance of)--> Q43605 'French Open'
    #    --P361 (part of) --> Q102113 'Grand Slam of tennis' <-- wdt:P361(part of)-- RESULT

# P765'), ('pName', 'surface played on')
    
# FOUND surface played on from Q43605 with 2 degrees of depth
# now lets found all three from Grand Slam of tennis

queryString = """
SELECT DISTINCT ?obj ?objName ?obj2 ?obj2Name
WHERE {
   # BACKWARD DISCOVERY
   wd:Q102113 ^wdt:P361 ?obj.
   # ?obj wdt:P765 ?obj2 .
   
   # get the label
   # ?obj sc:name ?objName.
   # ?obj2 sc:name ?obj2Name.
}
LIMIT 50

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('obj', 'http://www.wikidata.org/entity/Q43605'), ('objName', 'French Open'), ('obj2', 'http://www.wikidata.org/entity/Q198718'), ('obj2Name', 'clay court')]
# [('obj', 'http://www.wikidata.org/entity/Q123577'), ('objName', 'US Open'), ('obj2', 'http://www.wikidata.org/entity/Q1330871'), ('obj2Name', 'hardcourt')]
# [('obj', 'http://www.wikidata.org/entity/Q60874'), ('objName', 'Australian Open'), ('obj2', 'http://www.wikidata.org/entity/Q1330871'), ('obj2Name', 'hardcourt')]
# [('obj', 'http://www.wikidata.org/entity/Q60874'), ('objName', 'Australian Open'), ('obj2', 'http://www.wikidata.org/entity/Q1151291'), ('obj2Name', 'grass court')]
# [('obj', 'http://www.wikidata.org/entity/Q41520'), ('objName', 'Wimbledon Championships'), ('obj2', 'http://www.wikidata.org/entity/Q1151291'), ('obj2Name', 'grass court')]
# 5

# %%
##Find the three different type of possible surfaces in a tennis court (the result set must be a list of three couples surface IRI and label).

# Q1426 (Roger Federer) 
    #    --P2522 (victory)--> Q741573 '2009 French Open – Men's Singles'
    #    --P361 (part of)--> Q381118 '2009 French Open'  
    #    --P31 (instance of)--> Q43605 'French Open'
    #    --P361 (part of) --> Q102113 'Grand Slam of tennis' <-- wdt:P361(part of)-- RESULT

# P765'), ('pName', 'surface played on')
    
# FOUND surface played on from Q43605 with 2 degrees of depth
# now lets found all three from Grand Slam of tennis
# renaming variables

queryString = """
SELECT DISTINCT ?event ?eventName ?surface ?surfaceName
WHERE {
   # BACKWARD DISCOVERY
   wd:Q102113 ^wdt:P361 ?event.
   # ?event wdt:P765 ?surface .
   
   # get the label
   # ?event sc:name ?eventName.
   # ?surface sc:name ?surfaceName.
}
LIMIT 50

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('event', 'http://www.wikidata.org/entity/Q43605'), ('eventName', 'French Open'), ('surface', 'http://www.wikidata.org/entity/Q198718'), ('surfaceName', 'clay court')]
# [('event', 'http://www.wikidata.org/entity/Q123577'), ('eventName', 'US Open'), ('surface', 'http://www.wikidata.org/entity/Q1330871'), ('surfaceName', 'hardcourt')]
# [('event', 'http://www.wikidata.org/entity/Q60874'), ('eventName', 'Australian Open'), ('surface', 'http://www.wikidata.org/entity/Q1330871'), ('surfaceName', 'hardcourt')]
# [('event', 'http://www.wikidata.org/entity/Q60874'), ('eventName', 'Australian Open'), ('surface', 'http://www.wikidata.org/entity/Q1151291'), ('surfaceName', 'grass court')]
# [('event', 'http://www.wikidata.org/entity/Q41520'), ('eventName', 'Wimbledon Championships'), ('surface', 'http://www.wikidata.org/entity/Q1151291'), ('surfaceName', 'grass court')]
# 5

# %%
##Find the three different type of possible surfaces in a tennis court (the result set must be a list of three couples surface IRI and label).

# Q1426 (Roger Federer) 
    #    --P2522 (victory)--> Q741573 '2009 French Open – Men's Singles'
    #    --P361 (part of)--> Q381118 '2009 French Open'  
    #    --P31 (instance of)--> Q43605 'French Open'
    #    --P361 (part of) --> Q102113 'Grand Slam of tennis' <-- wdt:P361(part of)-- RESULT

# P765'), ('pName', 'surface played on')
    
# FOUND surface played on from Q43605 with 2 degrees of depth
# now lets found all three from Grand Slam of tennis
# renaming variables
# lets group by surface to remove duplicated
queryString = """

SELECT DISTINCT ?surface ?surfaceName
WHERE {
   # BACKWARD DISCOVERY
   wd:Q102113 ^wdt:P361 ?event.
   # ?event wdt:P765 ?surface .
   
   # get the label
   # ?event sc:name ?eventName.
   # ?surface sc:name ?surfaceName.
}
GROUP BY ?surface ?surfaceName
LIMIT 50

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('surface', 'http://www.wikidata.org/entity/Q1151291'), ('surfaceName', 'grass court')]
# [('surface', 'http://www.wikidata.org/entity/Q1330871'), ('surfaceName', 'hardcourt')]
# [('surface', 'http://www.wikidata.org/entity/Q198718'), ('surfaceName', 'clay court')]
# 3

# %% [markdown]
# ### Final query for this task

# %%
##Find the three different type of possible surfaces in a tennis court (the result set must be a list of three couples surface IRI and label).
#    Q102113 'Grand Slam of tennis' <-- wdt:P361(part of)-- ?event --wdt:P765(surface played on)--> ?surface

queryString = """

# Retrieving distinct BJP of surfaces
SELECT DISTINCT ?surface ?surfaceName
WHERE {
   # RETRIEVING ALL THE SURFACE OF EACH EVENT IN Grand Slam of Tennis
   wd:Q102113 ^wdt:P361 ?event.
   # ?event wdt:P765 ?surface .
   
   # getting the labels
   # ?event sc:name ?eventName.
   # ?surface sc:name ?surfaceName.
}
# Grouping so I can remove duplicates
GROUP BY ?surface ?surfaceName
LIMIT 50

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('surface', 'http://www.wikidata.org/entity/Q1151291'), ('surfaceName', 'grass court')]
# [('surface', 'http://www.wikidata.org/entity/Q1330871'), ('surfaceName', 'hardcourt')]
# [('surface', 'http://www.wikidata.org/entity/Q198718'), ('surfaceName', 'clay court')]
# 3

# %% [markdown]
# ## Task 5
# Return the tournaments played in the 2018 Wimbledon Championships edition with the related winners (hint: men and women do not play together, there are two distinct tournament ) (the result set must be a list of elements with tournament IRI and label, and winner IRI and label).

# %%
# write your queries

# Return the tournaments played in the 2018 Wimbledon Championships edition with the related winners 
# (hint: men and women do not play together, there are two distinct tournament ) 
# (the result set must be a list of elements with tournament IRI and label, and winner IRI and label).

# from task3 [('obj', 'http://www.wikidata.org/entity/Q41520'), ('objName', 'Wimbledon Championships')]

# Trying to explore more from Wimbledon Championships to get the specific edition in the task
queryString = """

SELECT DISTINCT ?p ?pName ?o ?oName
WHERE {
   wd:Q41520 ?p ?o.
   # get the label
   # ?p sc:name ?pName.
   # ?o sc:name ?oName.
}
LIMIT 50

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P664'), ('pName', 'organizer'), ('o', 'http://www.wikidata.org/entity/Q815369'), ('oName', 'All England Lawn Tennis and Croquet Club')]
# [('p', 'http://www.wikidata.org/prop/direct/P276'), ('pName', 'location'), ('o', 'http://www.wikidata.org/entity/Q815369'), ('oName', 'All England Lawn Tennis and Croquet Club')]
# [('p', 'http://www.wikidata.org/prop/direct/P664'), ('pName', 'organizer'), ('o', 'http://www.wikidata.org/entity/Q223041'), ('oName', 'International Tennis Federation')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q13219666'), ('oName', 'tennis tournament')]
# [('p', 'http://www.wikidata.org/prop/direct/P17'), ('pName', 'country'), ('o', 'http://www.wikidata.org/entity/Q145'), ('oName', 'United Kingdom')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('o', 'http://www.wikidata.org/entity/Q18608583'), ('oName', 'recurring sporting event')]
# [('p', 'http://www.wikidata.org/prop/direct/P641'), ('pName', 'sport'), ('o', 'http://www.wikidata.org/entity/Q847'), ('oName', 'tennis')]
# [('p', 'http://www.wikidata.org/prop/direct/P765'), ('pName', 'surface played on'), ('o', 'http://www.wikidata.org/entity/Q1151291'), ('oName', 'grass court')]
# [('p', 'http://www.wikidata.org/prop/direct/P7959'), ('pName', 'historic county'), ('o', 'http://www.wikidata.org/entity/Q67443130'), ('oName', 'Surrey')]
# [('p', 'http://www.wikidata.org/prop/direct/P361'), ('pName', 'part of'), ('o', 'http://www.wikidata.org/entity/Q102113'), ('oName', 'Grand Slam of tennis')]
# [('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q736742'), ('oName', 'Wimbledon')]
# [('p', 'http://www.wikidata.org/prop/direct/P664'), ('pName', 'organizer'), ('o', 'http://www.wikidata.org/entity/Q1337913'), ('oName', 'Lawn Tennis Association')]
# [('p', 'http://www.wikidata.org/prop/direct/P2354'), ('pName', 'has list'), ('o', 'http://www.wikidata.org/entity/Q6585893'), ('oName', 'list of Wimbledon singles finalists during the open era')]
# [('p', 'http://www.wikidata.org/prop/direct/P1687'), ('pName', 'Wikidata property'), ('o', 'http://www.wikidata.org/entity/P4503'), ('oName', 'Wimbledon player ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1424'), ('pName', "topic's main template"), ('o', 'http://www.wikidata.org/entity/Q43323825'), ('oName', 'Template:Wimbledon player')]
# [('p', 'http://www.wikidata.org/prop/direct/P1889'), ('pName', 'different from'), ('o', 'http://www.wikidata.org/entity/Q206375'), ('oName', 'Wimbledon')]
# [('p', 'http://www.wikidata.org/prop/direct/P910'), ('pName', "topic's main category"), ('o', 'http://www.wikidata.org/entity/Q5326534'), ('oName', 'Category:The Championships, Wimbledon')]
# [('p', 'http://www.wikidata.org/prop/direct/P4622'), ('pName', 'trophy awarded'), ('o', 'http://www.wikidata.org/entity/Q7920608'), ('oName', 'Venus Rosewater Dish')]
# 18

# %%
# Return the tournaments played in the 2018 Wimbledon Championships edition with the related winners 
# (hint: men and women do not play together, there are two distinct tournament ) 
# (the result set must be a list of elements with tournament IRI and label, and winner IRI and label).

# Q41520 ('Wimbledon Championships') --P2354 (has list)-> Q6585893 'list of Wimbledon singles finalists during the open era'

# Trying to explore more from Wimbledon Championships to get the specific edition in the task
# trying to get the list of finalist from Q6585893 'list of Wimbledon singles finalists during the open era'
queryString = """

SELECT DISTINCT ?p ?pName ?o ?oName
WHERE {
   wd:Q6585893 ?p ?o.
   # get the label
   # ?p sc:name ?pName.
   # ?o sc:name ?oName.
}
LIMIT 50

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P360'), ('pName', 'is a list of'), ('o', 'http://www.wikidata.org/entity/Q5'), ('oName', 'human')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('o', 'http://www.wikidata.org/entity/Q19692233'), ('oName', 'Wikimedia list of persons')]
# 2

# %%
# Return the tournaments played in the 2018 Wimbledon Championships edition with the related winners 
# (hint: men and women do not play together, there are two distinct tournament ) 
# (the result set must be a list of elements with tournament IRI and label, and winner IRI and label).

# Q41520 ('Wimbledon Championships') --P2354 (has list)-> Q6585893 'list of Wimbledon singles finalists during the open era'

# Trying to explore more from Wimbledon Championships to get the specific edition in the task
# trying to get the list of finalist from Q6585893 'list of Wimbledon singles finalists during the open era'
# BACKWARD
queryString = """

SELECT DISTINCT ?s ?sName ?p ?pName
WHERE {
   # BACKWARD DISCOVERY
   # ?s ?p wd:Q6585893.
   # get the label
   # ?p sc:name ?pName.
   # ?s sc:name ?sName.
}
LIMIT 50

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('s', 'http://www.wikidata.org/entity/Q41520'), ('sName', 'Wimbledon Championships'), ('p', 'http://www.wikidata.org/prop/direct/P2354'), ('pName', 'has list')]
# 1

# %%
#BACKWARD WIMBLEDON CHAMPIONSHIPS

# %%
# Return the tournaments played in the 2018 Wimbledon Championships edition with the related winners 
# (hint: men and women do not play together, there are two distinct tournament ) 
# (the result set must be a list of elements with tournament IRI and label, and winner IRI and label).

# Q41520 ('Wimbledon Championships') --P2354 (has list)-> Q6585893 'list of Wimbledon singles finalists during the open era'

# Trying to explore more from Wimbledon Championships to get the specific edition in the task

queryString = """

SELECT DISTINCT ?s ?sName ?p ?pName
WHERE {
   # BACKWARD DISCOVERY
   # ?s ?p wd:Q41520.
   # get the label
   # ?p sc:name ?pName.
   # ?s sc:name ?sName.
}
LIMIT 50

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('s', 'http://www.wikidata.org/entity/Q268871'), ('sName', '2004 Wimbledon Championships'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q173961'), ('sName', '1978 Wimbledon Championships'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q925026'), ('sName', '1971 Wimbledon Championships'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q15854765'), ('sName', '2014 Wimbledon Championships'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q30085309'), ('sName', '2018 Wimbledon Championships'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q437350'), ('sName', 'Doris Metaxa'), ('p', 'http://www.wikidata.org/prop/direct/P1344'), ('pName', 'participant in')]
# [('s', 'http://www.wikidata.org/entity/Q745901'), ('sName', '1974 Wimbledon Championships'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q655368'), ('sName', '1955 Wimbledon Championships'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q655378'), ('sName', '1956 Wimbledon Championships'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q657950'), ('sName', '1957 Wimbledon Championships'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q657962'), ('sName', '1958 Wimbledon Championships'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q2273996'), ('sName', 'Giorgio de Stefani'), ('p', 'http://www.wikidata.org/prop/direct/P1344'), ('pName', 'participant in')]
# [('s', 'http://www.wikidata.org/entity/Q2296335'), ('sName', '1881 Wimbledon Championship'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q2297185'), ('sName', '1882 Wimbledon Championship'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q522860'), ('sName', '1883 Wimbledon Championship'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q27862706'), ('sName', 'Carol-Ann Kalogeropoulos'), ('p', 'http://www.wikidata.org/prop/direct/P1344'), ('pName', 'participant in')]
# [('s', 'http://www.wikidata.org/entity/Q3339850'), ('sName', 'Nikos Kalogeropoulos'), ('p', 'http://www.wikidata.org/prop/direct/P1344'), ('pName', 'participant in')]
# [('s', 'http://www.wikidata.org/entity/Q20127632'), ('sName', '2016 Wimbledon Championships'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q934978'), ('sName', '1988 Wimbledon Championships'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q388312'), ('sName', '2008 Wimbledon Championships'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q1049018'), ('sName', '1980 Wimbledon Championships'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q404337'), ('sName', '1929 Wimbledon Championships'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q404437'), ('sName', '1930 Wimbledon Championships'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q404791'), ('sName', '1933 Wimbledon Championships'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q855690'), ('sName', '1968 Wimbledon Championships'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q29743947'), ('sName', 'Léopold de Borman'), ('p', 'http://www.wikidata.org/prop/direct/P1344'), ('pName', 'participant in')]
# [('s', 'http://www.wikidata.org/entity/Q577138'), ('sName', '1954 Wimbledon Championships'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q244370'), ('sName', '2009 Wimbledon Championships'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q2849415'), ('sName', 'Angelikí Kanellopoúlou'), ('p', 'http://www.wikidata.org/prop/direct/P1344'), ('pName', 'participant in')]
# [('s', 'http://www.wikidata.org/entity/Q18410121'), ('sName', '2015 Wimbledon Championships'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q2121893'), ('sName', '1903 Wimbledon Championships'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q476638'), ('sName', '2010 Wimbledon Championships'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q740252'), ('sName', '1976 Wimbledon Championships'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q911804'), ('sName', '1969 Wimbledon Championships'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q925733'), ('sName', '1970 Wimbledon Championships'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q2120586'), ('sName', '1899 Wimbledon Championships'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q2120595'), ('sName', '1911 Wimbledon Championships'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q501879'), ('sName', '1946 Wimbledon Championships'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q2119702'), ('sName', '1910 Wimbledon Championships'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q2119706'), ('sName', '1898 Wimbledon Championships'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q2119719'), ('sName', '1908 Wimbledon Championships'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q2119732'), ('sName', '1901 Wimbledon Championships'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q2120599'), ('sName', '1909 Wimbledon Championships'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q2121907'), ('sName', '1900 Wimbledon Championships'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q1048601'), ('sName', '1981 Wimbledon Championships'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q1281192'), ('sName', '1905 Wimbledon Championships'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q1399137'), ('sName', '1897 Wimbledon Championships'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q1737828'), ('sName', '1890 Wimbledon Championships'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q337130'), ('sName', '1927 Wimbledon Championships'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q337138'), ('sName', '1928 Wimbledon Championships'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# 50

# %%
# Return the tournaments played in the 2018 Wimbledon Championships edition with the related winners 
# (hint: men and women do not play together, there are two distinct tournament ) 
# (the result set must be a list of elements with tournament IRI and label, and winner IRI and label).

# Q41520 ('Wimbledon Championships') --P2354 (has list)-> Q6585893 'list of Wimbledon singles finalists during the open era'

# Trying to explore more from Wimbledon Championships to get the specific edition in the task
# REGEX for 2018
queryString = """

SELECT DISTINCT ?s ?sName ?p ?pName
WHERE {
   # BACKWARD DISCOVERY
   # ?s ?p wd:Q41520.
   # get the label
   # ?p sc:name ?pName.
   # ?s sc:name ?sName.
   FILTER REGEX(?sName, ".2018*")
}
LIMIT 50

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# Empty

# %%
# Return the tournaments played in the 2018 Wimbledon Championships edition with the related winners 
# (hint: men and women do not play together, there are two distinct tournament ) 
# (the result set must be a list of elements with tournament IRI and label, and winner IRI and label).

# Q41520 ('Wimbledon Championships') --P2354 (has list)-> Q6585893 'list of Wimbledon singles finalists during the open era'

# Trying to explore more from Wimbledon Championships to get the specific edition in the task
# REGEX for 2018
queryString = """

SELECT DISTINCT ?s ?sName ?p ?pName
WHERE {
   # BACKWARD DISCOVERY
   # ?s ?p wd:Q41520.
   # get the label
   # ?p sc:name ?pName.
   # ?s sc:name ?sName.
   FILTER REGEX(?sName, ".*2018*")
}
LIMIT 50

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('s', 'http://www.wikidata.org/entity/Q18410121'), ('sName', '2015 Wimbledon Championships'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q559726'), ('sName', '2013 Wimbledon Championships'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q30085309'), ('sName', '2018 Wimbledon Championships'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q54093953'), ('sName', '2019 Wimbledon Championships'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q245073'), ('sName', '2011 Wimbledon Championships'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q15854765'), ('sName', '2014 Wimbledon Championships'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q289587'), ('sName', '2012 Wimbledon Championships'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q20127632'), ('sName', '2016 Wimbledon Championships'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q25344121'), ('sName', '2017 Wimbledon Championships'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q476638'), ('sName', '2010 Wimbledon Championships'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# 10

# %%
# Return the tournaments played in the 2018 Wimbledon Championships edition with the related winners 
# (hint: men and women do not play together, there are two distinct tournament ) 
# (the result set must be a list of elements with tournament IRI and label, and winner IRI and label).

# Q41520 ('Wimbledon Championships') --P2354 (has list)-> Q6585893 'list of Wimbledon singles finalists during the open era'

# Trying to explore more from Wimbledon Championships to get the specific edition in the task
# REGEX for 2018
queryString = """

SELECT DISTINCT ?s ?sName ?p ?pName
WHERE {
   # BACKWARD DISCOVERY
   # ?s ?p wd:Q41520.
   # get the label
   # ?p sc:name ?pName.
   # ?s sc:name ?sName.
   FILTER REGEX(?sName, "2018.*")
}
LIMIT 50

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('s', 'http://www.wikidata.org/entity/Q30085309'), ('sName', '2018 Wimbledon Championships'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# 1

# %%
# Return the tournaments played in the 2018 Wimbledon Championships edition with the related winners 
# (hint: men and women do not play together, there are two distinct tournament ) 
# (the result set must be a list of elements with tournament IRI and label, and winner IRI and label).

# Q41520 ('Wimbledon Championships') <---P31 instance of -- Q30085309 '2018 Wimbledon Championships'

# FOUND THE championships, now lets find the winners
queryString = """

SELECT DISTINCT ?p ?pName ?o ?oName 
WHERE {
   wd:Q30085309 ?p ?o.
   
   # get the label
   # ?p sc:name ?pName.
   # ?o sc:name ?oName.
}
LIMIT 50

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('o', 'http://www.wikidata.org/entity/Q30098268'), ('oName', "2018 Wimbledon Championships – Women's Singles")]
# [('p', 'http://www.wikidata.org/prop/direct/P17'), ('pName', 'country'), ('o', 'http://www.wikidata.org/entity/Q145'), ('oName', 'United Kingdom')]
# [('p', 'http://www.wikidata.org/prop/direct/P276'), ('pName', 'location'), ('o', 'http://www.wikidata.org/entity/Q84'), ('oName', 'London')]
# [('p', 'http://www.wikidata.org/prop/direct/P641'), ('pName', 'sport'), ('o', 'http://www.wikidata.org/entity/Q847'), ('oName', 'tennis')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('o', 'http://www.wikidata.org/entity/Q47345468'), ('oName', 'tennis tournament edition')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('o', 'http://www.wikidata.org/entity/Q41520'), ('oName', 'Wimbledon Championships')]
# [('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q736742'), ('oName', 'Wimbledon')]
# [('p', 'http://www.wikidata.org/prop/direct/P155'), ('pName', 'follows'), ('o', 'http://www.wikidata.org/entity/Q25344121'), ('oName', '2017 Wimbledon Championships')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('o', 'http://www.wikidata.org/entity/Q32358401'), ('oName', '2018 Wimbledon Championships – Mixed Doubles')]
# [('p', 'http://www.wikidata.org/prop/direct/P156'), ('pName', 'followed by'), ('o', 'http://www.wikidata.org/entity/Q54093953'), ('oName', '2019 Wimbledon Championships')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('o', 'http://www.wikidata.org/entity/Q32357790'), ('oName', "2018 Wimbledon Championships – Men's Doubles")]
# [('p', 'http://www.wikidata.org/prop/direct/P910'), ('pName', "topic's main category"), ('o', 'http://www.wikidata.org/entity/Q53582240'), ('oName', 'Category:2018 Wimbledon Championships')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('o', 'http://www.wikidata.org/entity/Q32356704'), ('oName', "2018 Wimbledon Championships – Women's Doubles")]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('o', 'http://www.wikidata.org/entity/Q55381839'), ('oName', "2018 Wimbledon Championships – Girls' Singles")]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('o', 'http://www.wikidata.org/entity/Q54961494'), ('oName', "2018 Wimbledon Championships – Men's Singles")]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('o', 'http://www.wikidata.org/entity/Q55410290'), ('oName', "2018 Wimbledon Championships – Girls' Doubles")]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('o', 'http://www.wikidata.org/entity/Q55410361'), ('oName', "2018 Wimbledon Championships – Boys' Doubles")]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('o', 'http://www.wikidata.org/entity/Q55455404'), ('oName', "2018 Wimbledon Championships – Wheelchair Women's Singles")]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('o', 'http://www.wikidata.org/entity/Q55381833'), ('oName', "2018 Wimbledon Championships – Boys' Singles")]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('o', 'http://www.wikidata.org/entity/Q55455423'), ('oName', "2018 Wimbledon Championships – Wheelchair Women's Doubles")]
# 20

# %%
# ALL SUBTOURNAMENTS OF 2018 Wimbledon Championships edition

# %%
# Return the tournaments played in the 2018 Wimbledon Championships edition with the related winners 
# (hint: men and women do not play together, there are two distinct tournament ) 
# (the result set must be a list of elements with tournament IRI and label, and winner IRI and label).

# Q30085309 '2018 Wimbledon Championships' --P31 instance of --> Q41520 ('Wimbledon Championships');
#                                          --P527 ('has part')-->

# trying to find all subtuornaments of Q30085309 '2018 Wimbledon Championships'

queryString = """

SELECT DISTINCT ?o ?oName 
WHERE {
   wd:Q30085309 wdt:P527 ?o.
   
   # get the label
   # ?o sc:name ?oName.
}
LIMIT 50

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('o', 'http://www.wikidata.org/entity/Q30098268'), ('oName', "2018 Wimbledon Championships – Women's Singles")]
# [('o', 'http://www.wikidata.org/entity/Q32358401'), ('oName', '2018 Wimbledon Championships – Mixed Doubles')]
# [('o', 'http://www.wikidata.org/entity/Q32357790'), ('oName', "2018 Wimbledon Championships – Men's Doubles")]
# [('o', 'http://www.wikidata.org/entity/Q32356704'), ('oName', "2018 Wimbledon Championships – Women's Doubles")]
# [('o', 'http://www.wikidata.org/entity/Q55381839'), ('oName', "2018 Wimbledon Championships – Girls' Singles")]
# [('o', 'http://www.wikidata.org/entity/Q54961494'), ('oName', "2018 Wimbledon Championships – Men's Singles")]
# [('o', 'http://www.wikidata.org/entity/Q55410290'), ('oName', "2018 Wimbledon Championships – Girls' Doubles")]
# [('o', 'http://www.wikidata.org/entity/Q55410361'), ('oName', "2018 Wimbledon Championships – Boys' Doubles")]
# [('o', 'http://www.wikidata.org/entity/Q55455404'), ('oName', "2018 Wimbledon Championships – Wheelchair Women's Singles")]
# [('o', 'http://www.wikidata.org/entity/Q55381833'), ('oName', "2018 Wimbledon Championships – Boys' Singles")]
# [('o', 'http://www.wikidata.org/entity/Q55455423'), ('oName', "2018 Wimbledon Championships – Wheelchair Women's Doubles")]
# 11

# %%
# Return the tournaments played in the 2018 Wimbledon Championships edition with the related winners 
# (hint: men and women do not play together, there are two distinct tournament ) 
# (the result set must be a list of elements with tournament IRI and label, and winner IRI and label).

# Q30085309 '2018 Wimbledon Championships' --P31 instance of --> Q41520 ('Wimbledon Championships');
#                                          --P527 ('has part')--> Q30098268 "2018 Wimbledon Championships – Women's Singles"


# trying to find the winner of the subtuornament Q30098268 '2018 Wimbledon Championships – Women's Singles'

queryString = """

SELECT DISTINCT ?p ?pName ?o ?oName 
WHERE {
   wd:Q30098268 ?p ?o.
   
   # get the label
   # ?p sc:name ?pName.
   # ?o sc:name ?oName.
}
LIMIT 50

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P155'), ('pName', 'follows'), ('o', 'http://www.wikidata.org/entity/Q25344122'), ('oName', "2017 Wimbledon Championships – Women's Singles")]
# [('p', 'http://www.wikidata.org/prop/direct/P361'), ('pName', 'part of'), ('o', 'http://www.wikidata.org/entity/Q30085309'), ('oName', '2018 Wimbledon Championships')]
# [('p', 'http://www.wikidata.org/prop/direct/P2094'), ('pName', 'competition class'), ('o', 'http://www.wikidata.org/entity/Q16893403'), ('oName', "women's singles")]
# [('p', 'http://www.wikidata.org/prop/direct/P641'), ('pName', 'sport'), ('o', 'http://www.wikidata.org/entity/Q847'), ('oName', 'tennis')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('o', 'http://www.wikidata.org/entity/Q46190676'), ('oName', 'tennis event')]
# [('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner'), ('o', 'http://www.wikidata.org/entity/Q77178'), ('oName', 'Angelique Kerber')]
# [('p', 'http://www.wikidata.org/prop/direct/P156'), ('pName', 'followed by'), ('o', 'http://www.wikidata.org/entity/Q55749169'), ('oName', "2019 Wimbledon Championships – Women's Singles")]
# 7

# %%
# Return the tournaments played in the 2018 Wimbledon Championships edition with the related winners 
# (hint: men and women do not play together, there are two distinct tournament ) 
# (the result set must be a list of elements with tournament IRI and label, and winner IRI and label).

# Q30085309 '2018 Wimbledon Championships' --P31 instance of --> Q41520 ('Wimbledon Championships');
#                                          --P527 ('has part')--> Q30098268 "2018 Wimbledon Championships – Women's Singles"
# Q30098268 "2018 Wimbledon Championships – Women's Singles" --> P1346 ('winner') --> ?winner

# trying to find the winner of the subtuornament Q30098268 '2018 Wimbledon Championships – Women's Singles'


queryString = """

SELECT DISTINCT ?o ?oName 
WHERE {
   wd:Q30098268 wdt:P1346 ?o.
   
   # get the label 
   # ?o sc:name ?oName.
}
LIMIT 50

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('o', 'http://www.wikidata.org/entity/Q77178'), ('oName', 'Angelique Kerber')]
# 1

# %%
# Return the tournaments played in the 2018 Wimbledon Championships edition with the related winners 
# (hint: men and women do not play together, there are two distinct tournament ) 
# (the result set must be a list of elements with tournament IRI and label, and winner IRI and label).

# Q30085309 '2018 Wimbledon Championships' --P31 instance of --> Q41520 ('Wimbledon Championships') 
# Q30085309 --P527 ('has part')--> Q30098268 "2018 Wimbledon Championships – Women's Singles"
# Q30098268 "2018 Wimbledon Championships – Women's Singles" --> P1346 ('winner') --> ?winner

# now lets find the winner of each subtuornament of Q30085309 '2018 Wimbledon Championships'

queryString = """

SELECT DISTINCT ?subTournament ?subTournamentName ?winner ?winnerName
WHERE {
   wd:Q30085309 wdt:P527 ?subTournament.
   # ?subTournament wdt:P1346 ?winner.
   
   # get the label 
   # ?subTournament sc:name ?subTournamentName.
   # ?winner sc:name ?winnerName.
}
LIMIT 50

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('subTournament', 'http://www.wikidata.org/entity/Q32357790'), ('subTournamentName', "2018 Wimbledon Championships – Men's Doubles"), ('winner', 'http://www.wikidata.org/entity/Q53342'), ('winnerName', 'Mike Bryan')]
# [('subTournament', 'http://www.wikidata.org/entity/Q54961494'), ('subTournamentName', "2018 Wimbledon Championships – Men's Singles"), ('winner', 'http://www.wikidata.org/entity/Q5812'), ('winnerName', 'Novak Djokovic')]
# [('subTournament', 'http://www.wikidata.org/entity/Q30098268'), ('subTournamentName', "2018 Wimbledon Championships – Women's Singles"), ('winner', 'http://www.wikidata.org/entity/Q77178'), ('winnerName', 'Angelique Kerber')]
# [('subTournament', 'http://www.wikidata.org/entity/Q32356704'), ('subTournamentName', "2018 Wimbledon Championships – Women's Doubles"), ('winner', 'http://www.wikidata.org/entity/Q11052500'), ('winnerName', 'Barbora Krejčíková')]
# [('subTournament', 'http://www.wikidata.org/entity/Q55455423'), ('subTournamentName', "2018 Wimbledon Championships – Wheelchair Women's Doubles"), ('winner', 'http://www.wikidata.org/entity/Q16224602'), ('winnerName', 'Yui Kamiji')]
# [('subTournament', 'http://www.wikidata.org/entity/Q55381839'), ('subTournamentName', "2018 Wimbledon Championships – Girls' Singles"), ('winner', 'http://www.wikidata.org/entity/Q26840238'), ('winnerName', 'Iga Świątek')]
# [('subTournament', 'http://www.wikidata.org/entity/Q55455404'), ('subTournamentName', "2018 Wimbledon Championships – Wheelchair Women's Singles"), ('winner', 'http://www.wikidata.org/entity/Q24574661'), ('winnerName', 'Diede de Groot')]
# [('subTournament', 'http://www.wikidata.org/entity/Q55455423'), ('subTournamentName', "2018 Wimbledon Championships – Wheelchair Women's Doubles"), ('winner', 'http://www.wikidata.org/entity/Q24574661'), ('winnerName', 'Diede de Groot')]
# [('subTournament', 'http://www.wikidata.org/entity/Q32356704'), ('subTournamentName', "2018 Wimbledon Championships – Women's Doubles"), ('winner', 'http://www.wikidata.org/entity/Q3720044'), ('winnerName', 'Kateřina Siniaková')]
# [('subTournament', 'http://www.wikidata.org/entity/Q32358401'), ('subTournamentName', '2018 Wimbledon Championships – Mixed Doubles'), ('winner', 'http://www.wikidata.org/entity/Q2216368'), ('winnerName', 'Nicole Melichar-Martinez')]
# [('subTournament', 'http://www.wikidata.org/entity/Q32358401'), ('subTournamentName', '2018 Wimbledon Championships – Mixed Doubles'), ('winner', 'http://www.wikidata.org/entity/Q457476'), ('winnerName', 'Alexander Peya')]
# [('subTournament', 'http://www.wikidata.org/entity/Q55410361'), ('subTournamentName', "2018 Wimbledon Championships – Boys' Doubles"), ('winner', 'http://www.wikidata.org/entity/Q55569239'), ('winnerName', 'Yankı Erel')]
# [('subTournament', 'http://www.wikidata.org/entity/Q55410290'), ('subTournamentName', "2018 Wimbledon Championships – Girls' Doubles"), ('winner', 'http://www.wikidata.org/entity/Q44465805'), ('winnerName', 'Wang Xinyu')]
# [('subTournament', 'http://www.wikidata.org/entity/Q55410290'), ('subTournamentName', "2018 Wimbledon Championships – Girls' Doubles"), ('winner', 'http://www.wikidata.org/entity/Q41799108'), ('winnerName', 'Wang Xiyu')]
# [('subTournament', 'http://www.wikidata.org/entity/Q55381833'), ('subTournamentName', "2018 Wimbledon Championships – Boys' Singles"), ('winner', 'http://www.wikidata.org/entity/Q47516746'), ('winnerName', 'Tseng Chun-hsin')]
# 15

# %%
# Return the tournaments played in the 2018 Wimbledon Championships edition with the related winners 
# (hint: men and women do not play together, there are two distinct tournament ) 
# (the result set must be a list of elements with tournament IRI and label, and winner IRI and label).

# Q30085309 '2018 Wimbledon Championships' --P31 instance of --> Q41520 ('Wimbledon Championships') 
# Q30085309 --P527 ('has part')--> Q30098268 "2018 Wimbledon Championships – Women's Singles"
# Q30098268 "2018 Wimbledon Championships – Women's Singles" --> P1346 ('winner') --> ?winner

# now lets find the winner of each subtuornament of Q30085309 '2018 Wimbledon Championships'
# ORDERING to understand 
queryString = """

SELECT DISTINCT ?subTournament ?subTournamentName ?winner ?winnerName
WHERE {
   wd:Q30085309 wdt:P527 ?subTournament.
   # ?subTournament wdt:P1346 ?winner.
   
   # get the label 
   # ?subTournament sc:name ?subTournamentName.
   # ?winner sc:name ?winnerName.
}
ORDER BY ASC (?subTournamentName)
LIMIT 50

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('subTournament', 'http://www.wikidata.org/entity/Q55410361'), ('subTournamentName', "2018 Wimbledon Championships – Boys' Doubles"), ('winner', 'http://www.wikidata.org/entity/Q55569239'), ('winnerName', 'Yankı Erel')]
# [('subTournament', 'http://www.wikidata.org/entity/Q55381833'), ('subTournamentName', "2018 Wimbledon Championships – Boys' Singles"), ('winner', 'http://www.wikidata.org/entity/Q47516746'), ('winnerName', 'Tseng Chun-hsin')]
# [('subTournament', 'http://www.wikidata.org/entity/Q55410290'), ('subTournamentName', "2018 Wimbledon Championships – Girls' Doubles"), ('winner', 'http://www.wikidata.org/entity/Q44465805'), ('winnerName', 'Wang Xinyu')]
# [('subTournament', 'http://www.wikidata.org/entity/Q55410290'), ('subTournamentName', "2018 Wimbledon Championships – Girls' Doubles"), ('winner', 'http://www.wikidata.org/entity/Q41799108'), ('winnerName', 'Wang Xiyu')]
# [('subTournament', 'http://www.wikidata.org/entity/Q55381839'), ('subTournamentName', "2018 Wimbledon Championships – Girls' Singles"), ('winner', 'http://www.wikidata.org/entity/Q26840238'), ('winnerName', 'Iga Świątek')]
# [('subTournament', 'http://www.wikidata.org/entity/Q32357790'), ('subTournamentName', "2018 Wimbledon Championships – Men's Doubles"), ('winner', 'http://www.wikidata.org/entity/Q53342'), ('winnerName', 'Mike Bryan')]
# [('subTournament', 'http://www.wikidata.org/entity/Q54961494'), ('subTournamentName', "2018 Wimbledon Championships – Men's Singles"), ('winner', 'http://www.wikidata.org/entity/Q5812'), ('winnerName', 'Novak Djokovic')]
# [('subTournament', 'http://www.wikidata.org/entity/Q32358401'), ('subTournamentName', '2018 Wimbledon Championships – Mixed Doubles'), ('winner', 'http://www.wikidata.org/entity/Q2216368'), ('winnerName', 'Nicole Melichar-Martinez')]
# [('subTournament', 'http://www.wikidata.org/entity/Q32358401'), ('subTournamentName', '2018 Wimbledon Championships – Mixed Doubles'), ('winner', 'http://www.wikidata.org/entity/Q457476'), ('winnerName', 'Alexander Peya')]
# [('subTournament', 'http://www.wikidata.org/entity/Q55455423'), ('subTournamentName', "2018 Wimbledon Championships – Wheelchair Women's Doubles"), ('winner', 'http://www.wikidata.org/entity/Q16224602'), ('winnerName', 'Yui Kamiji')]
# [('subTournament', 'http://www.wikidata.org/entity/Q55455423'), ('subTournamentName', "2018 Wimbledon Championships – Wheelchair Women's Doubles"), ('winner', 'http://www.wikidata.org/entity/Q24574661'), ('winnerName', 'Diede de Groot')]
# [('subTournament', 'http://www.wikidata.org/entity/Q55455404'), ('subTournamentName', "2018 Wimbledon Championships – Wheelchair Women's Singles"), ('winner', 'http://www.wikidata.org/entity/Q24574661'), ('winnerName', 'Diede de Groot')]
# [('subTournament', 'http://www.wikidata.org/entity/Q32356704'), ('subTournamentName', "2018 Wimbledon Championships – Women's Doubles"), ('winner', 'http://www.wikidata.org/entity/Q11052500'), ('winnerName', 'Barbora Krejčíková')]
# [('subTournament', 'http://www.wikidata.org/entity/Q32356704'), ('subTournamentName', "2018 Wimbledon Championships – Women's Doubles"), ('winner', 'http://www.wikidata.org/entity/Q3720044'), ('winnerName', 'Kateřina Siniaková')]
# [('subTournament', 'http://www.wikidata.org/entity/Q30098268'), ('subTournamentName', "2018 Wimbledon Championships – Women's Singles"), ('winner', 'http://www.wikidata.org/entity/Q77178'), ('winnerName', 'Angelique Kerber')]
# 15

# %% [markdown]
# ### Final query for this task

# %%
# Return the tournaments played in the 2018 Wimbledon Championships edition with the related winners 
# (hint: men and women do not play together, there are two distinct tournament ) 
# (the result set must be a list of elements with tournament IRI and label, and winner IRI and label).

# Q30085309 '2018 Wimbledon Championships' --P31 instance of --> Q41520 ('Wimbledon Championships') 
# Q30085309 --P527 ('has part')--> Q30098268 "2018 Wimbledon Championships – Women's Singles"
# Q30098268 "2018 Wimbledon Championships – Women's Singles" --> P1346 ('winner') --> ?winner

# Q30085309 '2018 Wimbledon Championships' --P527 ('has part')--> ?tournament --P1346 ('winner')--> ?winner

queryString = """
# retrieving BGP of each sub turnament of Q30085309 with the BGP of its winner 

SELECT DISTINCT ?tournament ?tournamentName ?winner ?winnerName
WHERE {
   # Q30085309 '2018 Wimbledon Championships' --P527 ('has part')--> ?tournament
   wd:Q30085309 wdt:P527 ?tournament.
   
   #?tournament --> P1346 ('winner') --> ?winner
   # ?tournament wdt:P1346 ?winner.
   
   # get the label 
   # ?tournament sc:name ?tournamentName.
   # ?winner sc:name ?winnerName.
}
ORDER BY ASC (?tournamentName)
LIMIT 50

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('tournament', 'http://www.wikidata.org/entity/Q55410361'), ('tournamentName', "2018 Wimbledon Championships – Boys' Doubles"), ('winner', 'http://www.wikidata.org/entity/Q55569239'), ('winnerName', 'Yankı Erel')]
# [('tournament', 'http://www.wikidata.org/entity/Q55381833'), ('tournamentName', "2018 Wimbledon Championships – Boys' Singles"), ('winner', 'http://www.wikidata.org/entity/Q47516746'), ('winnerName', 'Tseng Chun-hsin')]
# [('tournament', 'http://www.wikidata.org/entity/Q55410290'), ('tournamentName', "2018 Wimbledon Championships – Girls' Doubles"), ('winner', 'http://www.wikidata.org/entity/Q44465805'), ('winnerName', 'Wang Xinyu')]
# [('tournament', 'http://www.wikidata.org/entity/Q55410290'), ('tournamentName', "2018 Wimbledon Championships – Girls' Doubles"), ('winner', 'http://www.wikidata.org/entity/Q41799108'), ('winnerName', 'Wang Xiyu')]
# [('tournament', 'http://www.wikidata.org/entity/Q55381839'), ('tournamentName', "2018 Wimbledon Championships – Girls' Singles"), ('winner', 'http://www.wikidata.org/entity/Q26840238'), ('winnerName', 'Iga Świątek')]
# [('tournament', 'http://www.wikidata.org/entity/Q32357790'), ('tournamentName', "2018 Wimbledon Championships – Men's Doubles"), ('winner', 'http://www.wikidata.org/entity/Q53342'), ('winnerName', 'Mike Bryan')]
# [('tournament', 'http://www.wikidata.org/entity/Q54961494'), ('tournamentName', "2018 Wimbledon Championships – Men's Singles"), ('winner', 'http://www.wikidata.org/entity/Q5812'), ('winnerName', 'Novak Djokovic')]
# [('tournament', 'http://www.wikidata.org/entity/Q32358401'), ('tournamentName', '2018 Wimbledon Championships – Mixed Doubles'), ('winner', 'http://www.wikidata.org/entity/Q2216368'), ('winnerName', 'Nicole Melichar-Martinez')]
# [('tournament', 'http://www.wikidata.org/entity/Q32358401'), ('tournamentName', '2018 Wimbledon Championships – Mixed Doubles'), ('winner', 'http://www.wikidata.org/entity/Q457476'), ('winnerName', 'Alexander Peya')]
# [('tournament', 'http://www.wikidata.org/entity/Q55455423'), ('tournamentName', "2018 Wimbledon Championships – Wheelchair Women's Doubles"), ('winner', 'http://www.wikidata.org/entity/Q16224602'), ('winnerName', 'Yui Kamiji')]
# [('tournament', 'http://www.wikidata.org/entity/Q55455423'), ('tournamentName', "2018 Wimbledon Championships – Wheelchair Women's Doubles"), ('winner', 'http://www.wikidata.org/entity/Q24574661'), ('winnerName', 'Diede de Groot')]
# [('tournament', 'http://www.wikidata.org/entity/Q55455404'), ('tournamentName', "2018 Wimbledon Championships – Wheelchair Women's Singles"), ('winner', 'http://www.wikidata.org/entity/Q24574661'), ('winnerName', 'Diede de Groot')]
# [('tournament', 'http://www.wikidata.org/entity/Q32356704'), ('tournamentName', "2018 Wimbledon Championships – Women's Doubles"), ('winner', 'http://www.wikidata.org/entity/Q11052500'), ('winnerName', 'Barbora Krejčíková')]
# [('tournament', 'http://www.wikidata.org/entity/Q32356704'), ('tournamentName', "2018 Wimbledon Championships – Women's Doubles"), ('winner', 'http://www.wikidata.org/entity/Q3720044'), ('winnerName', 'Kateřina Siniaková')]
# [('tournament', 'http://www.wikidata.org/entity/Q30098268'), ('tournamentName', "2018 Wimbledon Championships – Women's Singles"), ('winner', 'http://www.wikidata.org/entity/Q77178'), ('winnerName', 'Angelique Kerber')]
# 15

# %% [markdown]
# ## Task 6
# Consider the tennis players born after 1975, return who won more Grand Slams and cut the result to the top-10 (the result set must be a list of triples player IRI, label and #victories).

# %% [markdown]
# #### POSSIBLE SOLUTION
# 1) get all winners of Grand Slams
# 2) then check their dob
# 3) filter them (dob>1975)
# 4) order them
# 5) select top 10

# %%
# write your queries

# Consider the tennis players born after 1975, return who won more Grand Slams and cut the result to the top-10 (the result set must be a list of triples player IRI, label and #victories).

# from task3 [('obj', 'http://www.wikidata.org/entity/Q41520'), ('objName', 'Wimbledon Championships')]
# <---P31 instance of -- Q30085309 '2018 Wimbledon Championships'
# --P527 ('has part')--> Q30098268 "2018 Wimbledon Championships – Women's Singles" --> P1346 ('winner') -->

# 1) getting all winner of yearly grand slam

queryString = """

SELECT DISTINCT ?yearlyWimbledonTournament ?yearlyWimbledonTournamentName
WHERE {
   # BACKWARD DISCOVERY
   # ?yearlyWimbledonTournament ?p wd:Q41520.
   
   # get the label 
   # ?yearlyWimbledonTournament sc:name ?yearlyWimbledonTournamentName .
}
ORDER BY ASC (?yearlyWimbledonTournamentName)
LIMIT 50

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q1934049'), ('yearlyWimbledonTournamentName', '1877 Wimbledon Championship')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q1253069'), ('yearlyWimbledonTournamentName', '1878 Wimbledon Championships')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q726549'), ('yearlyWimbledonTournamentName', '1879 Wimbledon Championship')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q2296326'), ('yearlyWimbledonTournamentName', '1880 Wimbledon Championship')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q2296335'), ('yearlyWimbledonTournamentName', '1881 Wimbledon Championship')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q2297185'), ('yearlyWimbledonTournamentName', '1882 Wimbledon Championship')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q522860'), ('yearlyWimbledonTournamentName', '1883 Wimbledon Championship')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q1803935'), ('yearlyWimbledonTournamentName', '1884 Wimbledon Championships')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q1326511'), ('yearlyWimbledonTournamentName', '1885 Wimbledon Championships')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q47220'), ('yearlyWimbledonTournamentName', '1886 Wimbledon Championships')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q1724301'), ('yearlyWimbledonTournamentName', '1887 Wimbledon Championships')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q2120535'), ('yearlyWimbledonTournamentName', '1888 Wimbledon Championships')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q951238'), ('yearlyWimbledonTournamentName', '1889 Wimbledon Championships')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q1737828'), ('yearlyWimbledonTournamentName', '1890 Wimbledon Championships')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q584490'), ('yearlyWimbledonTournamentName', '1891 Wimbledon Championships')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q762595'), ('yearlyWimbledonTournamentName', '1892 Wimbledon Championships')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q2119713'), ('yearlyWimbledonTournamentName', '1893 Wimbledon Championships')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q978149'), ('yearlyWimbledonTournamentName', '1894 Wimbledon Championships')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q2120562'), ('yearlyWimbledonTournamentName', '1895 Wimbledon Championships')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q653092'), ('yearlyWimbledonTournamentName', '1896 Wimbledon Championships')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q1399137'), ('yearlyWimbledonTournamentName', '1897 Wimbledon Championships')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q2119706'), ('yearlyWimbledonTournamentName', '1898 Wimbledon Championships')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q2120586'), ('yearlyWimbledonTournamentName', '1899 Wimbledon Championships')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q2121907'), ('yearlyWimbledonTournamentName', '1900 Wimbledon Championships')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q2119732'), ('yearlyWimbledonTournamentName', '1901 Wimbledon Championships')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q2121902'), ('yearlyWimbledonTournamentName', '1902 Wimbledon Championships')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q2121893'), ('yearlyWimbledonTournamentName', '1903 Wimbledon Championships')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q2119724'), ('yearlyWimbledonTournamentName', '1904 Wimbledon Championships')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q1281192'), ('yearlyWimbledonTournamentName', '1905 Wimbledon Championships')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q1644372'), ('yearlyWimbledonTournamentName', '1906 Wimbledon Championships')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q584200'), ('yearlyWimbledonTournamentName', '1907 Wimbledon Championships')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q2119719'), ('yearlyWimbledonTournamentName', '1908 Wimbledon Championships')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q2120599'), ('yearlyWimbledonTournamentName', '1909 Wimbledon Championships')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q2119702'), ('yearlyWimbledonTournamentName', '1910 Wimbledon Championships')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q2120595'), ('yearlyWimbledonTournamentName', '1911 Wimbledon Championships')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q2121913'), ('yearlyWimbledonTournamentName', '1912 Wimbledon Championships')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q1693428'), ('yearlyWimbledonTournamentName', '1913 Wimbledon Championships')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q2119696'), ('yearlyWimbledonTournamentName', '1914 Wimbledon Championships')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q588012'), ('yearlyWimbledonTournamentName', '1919 Wimbledon Championships')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q1728917'), ('yearlyWimbledonTournamentName', '1920 Wimbledon Championships')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q2121875'), ('yearlyWimbledonTournamentName', '1921 Wimbledon Championships')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q1639966'), ('yearlyWimbledonTournamentName', '1922 Wimbledon Championships')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q212059'), ('yearlyWimbledonTournamentName', '1923 Wimbledon Championships')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q212073'), ('yearlyWimbledonTournamentName', '1924 Wimbledon Championships')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q219459'), ('yearlyWimbledonTournamentName', '1925 Wimbledon Championships')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q337124'), ('yearlyWimbledonTournamentName', '1926 Wimbledon Championships')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q337130'), ('yearlyWimbledonTournamentName', '1927 Wimbledon Championships')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q337138'), ('yearlyWimbledonTournamentName', '1928 Wimbledon Championships')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q404337'), ('yearlyWimbledonTournamentName', '1929 Wimbledon Championships')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q404437'), ('yearlyWimbledonTournamentName', '1930 Wimbledon Championships')]
# 50

# %%
# write your queries

# Consider the tennis players born after 1975, return who won more Grand Slams and cut the result to the top-10 (the result set must be a list of triples player IRI, label and #victories).

# from task3 [('obj', 'http://www.wikidata.org/entity/Q41520'), ('objName', 'Wimbledon Championships')]
# <---P31 instance of -- Q30085309 '2018 Wimbledon Championships'
# --P527 ('has part')--> Q30098268 "2018 Wimbledon Championships – Women's Singles" --> P1346 ('winner') -->

# 1) getting all winner of yearly grand slam

queryString = """

SELECT DISTINCT ?yearlyWimbledonTournament ?yearlyWimbledonTournamentName
WHERE {
   # BACKWARD DISCOVERY
   # ?yearlyWimbledonTournament ?p wd:Q41520.
   
   # get the label 
   # ?yearlyWimbledonTournament sc:name ?yearlyWimbledonTournamentName .
}
ORDER BY DESC (?yearlyWimbledonTournamentName)
LIMIT 50

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/P765'), ('yearlyWimbledonTournamentName', 'surface played on')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/P4503'), ('yearlyWimbledonTournamentName', 'Wimbledon player ID')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q837799'), ('yearlyWimbledonTournamentName', 'Wimbledon Effect')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q29473999'), ('yearlyWimbledonTournamentName', 'Vera Mattar')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q7920608'), ('yearlyWimbledonTournamentName', 'Venus Rosewater Dish')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q43323825'), ('yearlyWimbledonTournamentName', 'Template:Wimbledon player')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q3507351'), ('yearlyWimbledonTournamentName', 'Sylvie Jung')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q965205'), ('yearlyWimbledonTournamentName', 'Suzanne Schmitt')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q29525228'), ('yearlyWimbledonTournamentName', 'Suzanne Pannetier')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q469884'), ('yearlyWimbledonTournamentName', 'Spencer Gore')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q273491'), ('yearlyWimbledonTournamentName', 'Simonne Mathieu')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q3484531'), ('yearlyWimbledonTournamentName', 'Simone Barbier')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q3440332'), ('yearlyWimbledonTournamentName', 'Rolando Del Bello')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q3440119'), ('yearlyWimbledonTournamentName', 'Roland Journu')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q29110230'), ('yearlyWimbledonTournamentName', 'Pierre Grandguillot')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q29570086'), ('yearlyWimbledonTournamentName', 'Pierre Geelhand de Merxem')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q42365214'), ('yearlyWimbledonTournamentName', 'Peggy Dawson-Scott')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q3372146'), ('yearlyWimbledonTournamentName', 'Paul Rémy')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q1340559'), ('yearlyWimbledonTournamentName', 'Orlando Sirola')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q3491739'), ('yearlyWimbledonTournamentName', 'No. 3 Court')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q3491713'), ('yearlyWimbledonTournamentName', 'No. 2 Court')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q2306600'), ('yearlyWimbledonTournamentName', 'No. 1 Court')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q7040109'), ('yearlyWimbledonTournamentName', 'Nirupama Mankad')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q3339850'), ('yearlyWimbledonTournamentName', 'Nikos Kalogeropoulos')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q3300108'), ('yearlyWimbledonTournamentName', 'Maud Galtier')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q29743947'), ('yearlyWimbledonTournamentName', 'Léopold de Borman')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q31088104'), ('yearlyWimbledonTournamentName', 'Leon Norgarb')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q13415723'), ('yearlyWimbledonTournamentName', 'Kay Tuckey')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q3173111'), ('yearlyWimbledonTournamentName', 'Jean Le Sueur')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q3159748'), ('yearlyWimbledonTournamentName', 'Jacques Peten')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q3157780'), ('yearlyWimbledonTournamentName', 'Jacqueline Patorni')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q29407912'), ('yearlyWimbledonTournamentName', 'Jacqueline Kermina')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q3157726'), ('yearlyWimbledonTournamentName', 'Jacqueline Gallay')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q3147756'), ('yearlyWimbledonTournamentName', 'Ida Adamoff')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q3129826'), ('yearlyWimbledonTournamentName', 'Hella Kovac')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q102113'), ('yearlyWimbledonTournamentName', 'Grand Slam of tennis')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q2273996'), ('yearlyWimbledonTournamentName', 'Giorgio de Stefani')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q3105254'), ('yearlyWimbledonTournamentName', 'Gianni Cucelli')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q1344475'), ('yearlyWimbledonTournamentName', 'Georgios Caridia')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q3102800'), ('yearlyWimbledonTournamentName', 'Georges Grandguillot')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q43422349'), ('yearlyWimbledonTournamentName', 'Gaby Curtis')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q928741'), ('yearlyWimbledonTournamentName', 'Fausto Gardini')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q3037156'), ('yearlyWimbledonTournamentName', 'Dorothy Andrus')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q437350'), ('yearlyWimbledonTournamentName', 'Doris Metaxa')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q16002971'), ('yearlyWimbledonTournamentName', 'Domini Crosfield')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q2982531'), ('yearlyWimbledonTournamentName', 'Colette Rosambert')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q1260278'), ('yearlyWimbledonTournamentName', 'Christiane Mercelis')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q29871402'), ('yearlyWimbledonTournamentName', 'Charles Naeyaert')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q2603183'), ('yearlyWimbledonTournamentName', 'Centre Court')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q5326534'), ('yearlyWimbledonTournamentName', 'Category:The Championships, Wimbledon')]
# 50

# %%
# write your queries

# Consider the tennis players born after 1975, return who won more Grand Slams and cut the result to the top-10 (the result set must be a list of triples player IRI, label and #victories).

# from task3 [('obj', 'http://www.wikidata.org/entity/Q41520'), ('objName', 'Wimbledon Championships')]
# <---P31 instance of -- Q30085309 '2018 Wimbledon Championships'
# --P527 ('has part')--> Q30098268 "2018 Wimbledon Championships – Women's Singles" --> P1346 ('winner') -->

# 1) getting all winner of yearly grand slam

queryString = """

SELECT DISTINCT ?p ?pName
WHERE {
   # BACKWARD DISCOVERY
   # ?yearlyWimbledonTournament ?p wd:Q41520.
   
   # get the label 
   # ?yearlyWimbledonTournament sc:name ?yearlyWimbledonTournamentName .
   # ?p sc:name ?pName .
}
LIMIT 50

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P1423'), ('pName', 'template has topic')]
# [('p', 'http://www.wikidata.org/prop/direct/P1269'), ('pName', 'facet of')]
# [('p', 'http://www.wikidata.org/prop/direct/P1344'), ('pName', 'participant in')]
# [('p', 'http://www.wikidata.org/prop/direct/P138'), ('pName', 'named after')]
# [('p', 'http://www.wikidata.org/prop/direct/P2522'), ('pName', 'victory')]
# [('p', 'http://www.wikidata.org/prop/direct/P301'), ('pName', "category's main topic")]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('p', 'http://www.wikidata.org/prop/direct/P3450'), ('pName', 'sports season of league or competition')]
# [('p', 'http://www.wikidata.org/prop/direct/P361'), ('pName', 'part of')]
# [('p', 'http://www.wikidata.org/prop/direct/P466'), ('pName', 'occupant')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part')]
# [('p', 'http://www.wikidata.org/prop/direct/P710'), ('pName', 'participant')]
# [('p', 'http://www.wikidata.org/prop/direct/P1629'), ('pName', 'Wikidata item of this property')]
# [('p', 'http://www.wikidata.org/prop/direct/P1855'), ('pName', 'Wikidata property example')]
# 14

# %%
# write your queries

# Consider the tennis players born after 1975, return who won more Grand Slams and cut the result to the top-10 (the result set must be a list of triples player IRI, label and #victories).

# from task3 [('obj', 'http://www.wikidata.org/entity/Q41520'), ('objName', 'Wimbledon Championships')]
# <---P31 instance of -- Q30085309 '2018 Wimbledon Championships'
# --P527 ('has part')--> Q30098268 "2018 Wimbledon Championships – Women's Singles" --> P1346 ('winner') -->

# 1) getting all winner of yearly grand slam
queryString = """

SELECT DISTINCT ?yearlyWimbledonTournament ?yearlyWimbledonTournamentName
WHERE {
   # BACKWARD DISCOVERY
   # ?yearlyWimbledonTournament wdt:P31 wd:Q41520.
   
   # get the label 
   # ?yearlyWimbledonTournament sc:name ?yearlyWimbledonTournamentName .
}
ORDER BY  DESC (?yearlyWimbledonTournamentName)
LIMIT 50

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q107283026'), ('yearlyWimbledonTournamentName', '2022 Wimbledon Championships')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q92032430'), ('yearlyWimbledonTournamentName', '2021 Wimbledon Championships')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q54093953'), ('yearlyWimbledonTournamentName', '2019 Wimbledon Championships')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q30085309'), ('yearlyWimbledonTournamentName', '2018 Wimbledon Championships')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q25344121'), ('yearlyWimbledonTournamentName', '2017 Wimbledon Championships')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q20127632'), ('yearlyWimbledonTournamentName', '2016 Wimbledon Championships')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q18410121'), ('yearlyWimbledonTournamentName', '2015 Wimbledon Championships')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q15854765'), ('yearlyWimbledonTournamentName', '2014 Wimbledon Championships')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q559726'), ('yearlyWimbledonTournamentName', '2013 Wimbledon Championships')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q289587'), ('yearlyWimbledonTournamentName', '2012 Wimbledon Championships')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q245073'), ('yearlyWimbledonTournamentName', '2011 Wimbledon Championships')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q476638'), ('yearlyWimbledonTournamentName', '2010 Wimbledon Championships')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q244370'), ('yearlyWimbledonTournamentName', '2009 Wimbledon Championships')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q388312'), ('yearlyWimbledonTournamentName', '2008 Wimbledon Championships')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q746669'), ('yearlyWimbledonTournamentName', '2007 Wimbledon Championships')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q241184'), ('yearlyWimbledonTournamentName', '2006 Wimbledon Championships')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q746693'), ('yearlyWimbledonTournamentName', '2005 Wimbledon Championships')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q268871'), ('yearlyWimbledonTournamentName', '2004 Wimbledon Championships')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q832484'), ('yearlyWimbledonTournamentName', '2003 Wimbledon Championships')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q840901'), ('yearlyWimbledonTournamentName', '2002 Wimbledon Championships')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q912527'), ('yearlyWimbledonTournamentName', '2001 Wimbledon Championships')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q912491'), ('yearlyWimbledonTournamentName', '2000 Wimbledon Championships')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q727406'), ('yearlyWimbledonTournamentName', '1999 Wimbledon Championships')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q512632'), ('yearlyWimbledonTournamentName', '1998 Wimbledon Championships')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q912497'), ('yearlyWimbledonTournamentName', '1997 Wimbledon Championships')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q912478'), ('yearlyWimbledonTournamentName', '1996 Wimbledon Championships')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q572505'), ('yearlyWimbledonTournamentName', '1995 Wimbledon Championships')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q856533'), ('yearlyWimbledonTournamentName', '1994 Wimbledon Championships')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q278548'), ('yearlyWimbledonTournamentName', '1993 Wimbledon Championships')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q525952'), ('yearlyWimbledonTournamentName', '1992 Wimbledon Championships')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q780070'), ('yearlyWimbledonTournamentName', '1991 Wimbledon Championships')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q180151'), ('yearlyWimbledonTournamentName', '1990 Wimbledon Championships')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q935551'), ('yearlyWimbledonTournamentName', '1989 Wimbledon Championships')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q934978'), ('yearlyWimbledonTournamentName', '1988 Wimbledon Championships')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q951533'), ('yearlyWimbledonTournamentName', '1987 Wimbledon Championships')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q663357'), ('yearlyWimbledonTournamentName', '1986 Wimbledon Championships')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q383872'), ('yearlyWimbledonTournamentName', '1985 Wimbledon Championships')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q683224'), ('yearlyWimbledonTournamentName', '1984 Wimbledon Championships')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q1049023'), ('yearlyWimbledonTournamentName', '1983 Wimbledon Championships')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q729205'), ('yearlyWimbledonTournamentName', '1982 Wimbledon Championships')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q1048601'), ('yearlyWimbledonTournamentName', '1981 Wimbledon Championships')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q1049018'), ('yearlyWimbledonTournamentName', '1980 Wimbledon Championships')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q1049039'), ('yearlyWimbledonTournamentName', '1979 Wimbledon Championships')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q173961'), ('yearlyWimbledonTournamentName', '1978 Wimbledon Championships')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q658771'), ('yearlyWimbledonTournamentName', '1977 Wimbledon Championships')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q740252'), ('yearlyWimbledonTournamentName', '1976 Wimbledon Championships')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q536733'), ('yearlyWimbledonTournamentName', '1975 Wimbledon Championships')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q745901'), ('yearlyWimbledonTournamentName', '1974 Wimbledon Championships')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q521328'), ('yearlyWimbledonTournamentName', '1973 Wimbledon Championships')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q1049052'), ('yearlyWimbledonTournamentName', '1972 Wimbledon Championships')]
# 50

# %%
# write your queries

# Consider the tennis players born after 1975, return who won more Grand Slams and cut the result to the top-10 (the result set must be a list of triples player IRI, label and #victories).

# from task3 [('obj', 'http://www.wikidata.org/entity/Q41520'), ('objName', 'Wimbledon Championships')]
# <---P31 instance of -- Q30085309 '2018 Wimbledon Championships'
# --P527 ('has part')--> Q30098268 "2018 Wimbledon Championships – Women's Singles" --> P1346 ('winner') -->

# 1) getting all winner of yearly grand slam
queryString = """

SELECT DISTINCT ?yearlyWimbledonTournament ?yearlyWimbledonTournamentName
WHERE {
   # BACKWARD DISCOVERY
   # ?yearlyWimbledonTournament wdt:P31 wd:Q41520.
   
   # get the label 
   # ?yearlyWimbledonTournament sc:name ?yearlyWimbledonTournamentName .
}
ORDER BY  ASC (?yearlyWimbledonTournamentName)
LIMIT 50

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q1934049'), ('yearlyWimbledonTournamentName', '1877 Wimbledon Championship')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q1253069'), ('yearlyWimbledonTournamentName', '1878 Wimbledon Championships')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q726549'), ('yearlyWimbledonTournamentName', '1879 Wimbledon Championship')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q2296326'), ('yearlyWimbledonTournamentName', '1880 Wimbledon Championship')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q2296335'), ('yearlyWimbledonTournamentName', '1881 Wimbledon Championship')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q2297185'), ('yearlyWimbledonTournamentName', '1882 Wimbledon Championship')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q522860'), ('yearlyWimbledonTournamentName', '1883 Wimbledon Championship')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q1803935'), ('yearlyWimbledonTournamentName', '1884 Wimbledon Championships')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q1326511'), ('yearlyWimbledonTournamentName', '1885 Wimbledon Championships')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q47220'), ('yearlyWimbledonTournamentName', '1886 Wimbledon Championships')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q1724301'), ('yearlyWimbledonTournamentName', '1887 Wimbledon Championships')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q2120535'), ('yearlyWimbledonTournamentName', '1888 Wimbledon Championships')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q951238'), ('yearlyWimbledonTournamentName', '1889 Wimbledon Championships')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q1737828'), ('yearlyWimbledonTournamentName', '1890 Wimbledon Championships')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q584490'), ('yearlyWimbledonTournamentName', '1891 Wimbledon Championships')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q762595'), ('yearlyWimbledonTournamentName', '1892 Wimbledon Championships')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q2119713'), ('yearlyWimbledonTournamentName', '1893 Wimbledon Championships')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q978149'), ('yearlyWimbledonTournamentName', '1894 Wimbledon Championships')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q2120562'), ('yearlyWimbledonTournamentName', '1895 Wimbledon Championships')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q653092'), ('yearlyWimbledonTournamentName', '1896 Wimbledon Championships')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q1399137'), ('yearlyWimbledonTournamentName', '1897 Wimbledon Championships')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q2119706'), ('yearlyWimbledonTournamentName', '1898 Wimbledon Championships')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q2120586'), ('yearlyWimbledonTournamentName', '1899 Wimbledon Championships')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q2121907'), ('yearlyWimbledonTournamentName', '1900 Wimbledon Championships')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q2119732'), ('yearlyWimbledonTournamentName', '1901 Wimbledon Championships')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q2121902'), ('yearlyWimbledonTournamentName', '1902 Wimbledon Championships')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q2121893'), ('yearlyWimbledonTournamentName', '1903 Wimbledon Championships')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q2119724'), ('yearlyWimbledonTournamentName', '1904 Wimbledon Championships')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q1281192'), ('yearlyWimbledonTournamentName', '1905 Wimbledon Championships')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q1644372'), ('yearlyWimbledonTournamentName', '1906 Wimbledon Championships')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q584200'), ('yearlyWimbledonTournamentName', '1907 Wimbledon Championships')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q2119719'), ('yearlyWimbledonTournamentName', '1908 Wimbledon Championships')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q2120599'), ('yearlyWimbledonTournamentName', '1909 Wimbledon Championships')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q2119702'), ('yearlyWimbledonTournamentName', '1910 Wimbledon Championships')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q2120595'), ('yearlyWimbledonTournamentName', '1911 Wimbledon Championships')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q2121913'), ('yearlyWimbledonTournamentName', '1912 Wimbledon Championships')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q1693428'), ('yearlyWimbledonTournamentName', '1913 Wimbledon Championships')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q2119696'), ('yearlyWimbledonTournamentName', '1914 Wimbledon Championships')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q588012'), ('yearlyWimbledonTournamentName', '1919 Wimbledon Championships')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q1728917'), ('yearlyWimbledonTournamentName', '1920 Wimbledon Championships')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q2121875'), ('yearlyWimbledonTournamentName', '1921 Wimbledon Championships')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q1639966'), ('yearlyWimbledonTournamentName', '1922 Wimbledon Championships')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q212059'), ('yearlyWimbledonTournamentName', '1923 Wimbledon Championships')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q212073'), ('yearlyWimbledonTournamentName', '1924 Wimbledon Championships')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q219459'), ('yearlyWimbledonTournamentName', '1925 Wimbledon Championships')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q337124'), ('yearlyWimbledonTournamentName', '1926 Wimbledon Championships')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q337130'), ('yearlyWimbledonTournamentName', '1927 Wimbledon Championships')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q337138'), ('yearlyWimbledonTournamentName', '1928 Wimbledon Championships')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q404337'), ('yearlyWimbledonTournamentName', '1929 Wimbledon Championships')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q404437'), ('yearlyWimbledonTournamentName', '1930 Wimbledon Championships')]
# 50

# %%
# write your queries

# Consider the tennis players born after 1975, return who won more Grand Slams and cut the result to the top-10 (the result set must be a list of triples player IRI, label and #victories).

# from task3 [('obj', 'http://www.wikidata.org/entity/Q41520'), ('objName', 'Wimbledon Championships')]
# <---P31 instance of -- Q30085309 '2018 Wimbledon Championships'
# --P527 ('has part')--> Q30098268 "2018 Wimbledon Championships – Women's Singles" --> P1346 ('winner') -->

# 1) getting all winner of yearly grand slam
queryString = """

SELECT DISTINCT (COUNT(?yearlyWimbledonTournament ) AS ?totTournaments)
WHERE {
   # BACKWARD DISCOVERY
   # ?yearlyWimbledonTournament wdt:P31 wd:Q41520.
   
   # get the label 
   # ?yearlyWimbledonTournament sc:name ?yearlyWimbledonTournamentName .
}
LIMIT 50

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('totTournaments', '135')]
# 1

# %%
# write your queries

# Consider the tennis players born after 1975, return who won more Grand Slams and cut the result to the top-10 (the result set must be a list of triples player IRI, label and #victories).

# from task3 [('obj', 'http://www.wikidata.org/entity/Q41520'), ('objName', 'Wimbledon Championships')]
# <---P31 instance of -- Q30085309 '2018 Wimbledon Championships'
# --P527 ('has part')--> Q30098268 "2018 Wimbledon Championships – Women's Singles" --> P1346 ('winner') -->

# 1) getting all winner of yearly grand slam
queryString = """

SELECT DISTINCT (COUNT(?yearlyWimbledonTournament ) AS ?totTournaments)
WHERE {
   # BACKWARD DISCOVERY
   # ?yearlyWimbledonTournament ?p wd:Q41520.
   # ?yearlyWimbledonTournament wdt:P527 ?subTournament.
   
   # get the label 
   # ?yearlyWimbledonTournament sc:name ?yearlyWimbledonTournamentName .
}
LIMIT 50

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('totTournaments', '320')]
# 1

# %%
# write your queries

# Consider the tennis players born after 1975, return who won more Grand Slams and cut the result to the top-10 (the result set must be a list of triples player IRI, label and #victories).

# from task3 [('obj', 'http://www.wikidata.org/entity/Q41520'), ('objName', 'Wimbledon Championships')]
# <---P31 instance of -- Q30085309 '2018 Wimbledon Championships'
# --P527 ('has part')--> Q30098268 "2018 Wimbledon Championships – Women's Singles" --> P1346 ('winner') -->

# 1) getting all winner of yearly grand slam
queryString = """

SELECT (COUNT(?yearlyWimbledonTournament ) AS ?totTournaments){
    SELECT DISTINCT ?yearlyWimbledonTournament
    WHERE {
       # BACKWARD DISCOVERY
       # ?yearlyWimbledonTournament ?p wd:Q41520.
       # ?yearlyWimbledonTournament wdt:P527 ?subTournament.

       # get the label 
       # ?yearlyWimbledonTournament sc:name ?yearlyWimbledonTournamentName .
    }
}
LIMIT 50

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('totTournaments', '76')]
# 1

# %%
# write your queries

# Consider the tennis players born after 1975, return who won more Grand Slams and cut the result to the top-10 (the result set must be a list of triples player IRI, label and #victories).

# from task3 [('obj', 'http://www.wikidata.org/entity/Q41520'), ('objName', 'Wimbledon Championships')]
# <---P31 instance of -- Q30085309 '2018 Wimbledon Championships'
# --P527 ('has part')--> Q30098268 "2018 Wimbledon Championships – Women's Singles" --> P1346 ('winner') -->

# 1) getting all winner of yearly grand slam
queryString = """

SELECT DISTINCT ?yearlyWimbledonTournament ?yearlyWimbledonTournamentName ?subTournament ?subTournamentName ?winner ?winnerName
WHERE {
   # BACKWARD DISCOVERY
   # ?yearlyWimbledonTournament ?p wd:Q41520.
   # ?yearlyWimbledonTournament wdt:P527 ?subTournament.
   # ?subTournament wdt:P1346 ?winner.
   
   # get the label 
   # ?yearlyWimbledonTournament sc:name ?yearlyWimbledonTournamentName .
   # ?subTournament sc:name ?subTournamentName.
   # ?winner sc:name ?winnerName.
}
ORDER BY ASC (?subTournamentName)
LIMIT 50

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q1934049'), ('yearlyWimbledonTournamentName', '1877 Wimbledon Championship'), ('subTournament', 'http://www.wikidata.org/entity/Q1354887'), ('subTournamentName', '1877 Wimbledon Championship – singles'), ('winner', 'http://www.wikidata.org/entity/Q469884'), ('winnerName', 'Spencer Gore')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q1253069'), ('yearlyWimbledonTournamentName', '1878 Wimbledon Championships'), ('subTournament', 'http://www.wikidata.org/entity/Q1356483'), ('subTournamentName', '1878 Wimbledon Championship – singles'), ('winner', 'http://www.wikidata.org/entity/Q469922'), ('winnerName', 'Frank Hadow')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q726549'), ('yearlyWimbledonTournamentName', '1879 Wimbledon Championship'), ('subTournament', 'http://www.wikidata.org/entity/Q1357074'), ('subTournamentName', '1879 Wimbledon Championship – singles'), ('winner', 'http://www.wikidata.org/entity/Q538191'), ('winnerName', 'John Hartley')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q2296326'), ('yearlyWimbledonTournamentName', '1880 Wimbledon Championship'), ('subTournament', 'http://www.wikidata.org/entity/Q1355471'), ('subTournamentName', '1880 Wimbledon Championship – singles'), ('winner', 'http://www.wikidata.org/entity/Q538191'), ('winnerName', 'John Hartley')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q2296335'), ('yearlyWimbledonTournamentName', '1881 Wimbledon Championship'), ('subTournament', 'http://www.wikidata.org/entity/Q1356657'), ('subTournamentName', '1881 Wimbledon Championship – singles'), ('winner', 'http://www.wikidata.org/entity/Q365139'), ('winnerName', 'William Renshaw')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q2297185'), ('yearlyWimbledonTournamentName', '1882 Wimbledon Championship'), ('subTournament', 'http://www.wikidata.org/entity/Q1356370'), ('subTournamentName', '1882 Wimbledon Championship – singles'), ('winner', 'http://www.wikidata.org/entity/Q365139'), ('winnerName', 'William Renshaw')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q522860'), ('yearlyWimbledonTournamentName', '1883 Wimbledon Championship'), ('subTournament', 'http://www.wikidata.org/entity/Q1273149'), ('subTournamentName', '1883 Wimbledon Championship – singles'), ('winner', 'http://www.wikidata.org/entity/Q365139'), ('winnerName', 'William Renshaw')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q1803935'), ('yearlyWimbledonTournamentName', '1884 Wimbledon Championships'), ('subTournament', 'http://www.wikidata.org/entity/Q1235387'), ('subTournamentName', "1884 Wimbledon Championships – Gentlemen's Singles"), ('winner', 'http://www.wikidata.org/entity/Q365139'), ('winnerName', 'William Renshaw')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q1803935'), ('yearlyWimbledonTournamentName', '1884 Wimbledon Championships'), ('subTournament', 'http://www.wikidata.org/entity/Q1567939'), ('subTournamentName', "1884 Wimbledon Championships – Ladies' Singles"), ('winner', 'http://www.wikidata.org/entity/Q262027'), ('winnerName', 'Maud Watson')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q1326511'), ('yearlyWimbledonTournamentName', '1885 Wimbledon Championships'), ('subTournament', 'http://www.wikidata.org/entity/Q1356316'), ('subTournamentName', "1885 Wimbledon Championships – Gentlemen's Singles"), ('winner', 'http://www.wikidata.org/entity/Q365139'), ('winnerName', 'William Renshaw')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q1326511'), ('yearlyWimbledonTournamentName', '1885 Wimbledon Championships'), ('subTournament', 'http://www.wikidata.org/entity/Q729656'), ('subTournamentName', "1885 Wimbledon Championships – Ladies' Singles"), ('winner', 'http://www.wikidata.org/entity/Q262027'), ('winnerName', 'Maud Watson')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q47220'), ('yearlyWimbledonTournamentName', '1886 Wimbledon Championships'), ('subTournament', 'http://www.wikidata.org/entity/Q1797148'), ('subTournamentName', "1886 Wimbledon Championships – Gentlemen's Doubles"), ('winner', 'http://www.wikidata.org/entity/Q505764'), ('winnerName', 'Ernest Renshaw')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q47220'), ('yearlyWimbledonTournamentName', '1886 Wimbledon Championships'), ('subTournament', 'http://www.wikidata.org/entity/Q1356364'), ('subTournamentName', "1886 Wimbledon Championships – Gentlemen's Singles"), ('winner', 'http://www.wikidata.org/entity/Q365139'), ('winnerName', 'William Renshaw')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q47220'), ('yearlyWimbledonTournamentName', '1886 Wimbledon Championships'), ('subTournament', 'http://www.wikidata.org/entity/Q1560096'), ('subTournamentName', "1886 Wimbledon Championships – Ladies' Singles"), ('winner', 'http://www.wikidata.org/entity/Q273468'), ('winnerName', 'Blanche Bingley')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q2119702'), ('yearlyWimbledonTournamentName', '1910 Wimbledon Championships'), ('subTournament', 'http://www.wikidata.org/entity/Q2582773'), ('subTournamentName', "1910 Wimbledon Championships – Men's Doubles"), ('winner', 'http://www.wikidata.org/entity/Q710611'), ('winnerName', 'Major Ritchie')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q2119702'), ('yearlyWimbledonTournamentName', '1910 Wimbledon Championships'), ('subTournament', 'http://www.wikidata.org/entity/Q476944'), ('subTournamentName', "1910 Wimbledon Championships – Men's Singles"), ('winner', 'http://www.wikidata.org/entity/Q505788'), ('winnerName', 'Anthony Wilding')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q2119702'), ('yearlyWimbledonTournamentName', '1910 Wimbledon Championships'), ('subTournament', 'http://www.wikidata.org/entity/Q2483970'), ('subTournamentName', "1910 Wimbledon Championships – Women's Singles"), ('winner', 'http://www.wikidata.org/entity/Q53369'), ('winnerName', 'Dorothea Douglass')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q501879'), ('yearlyWimbledonTournamentName', '1946 Wimbledon Championships'), ('subTournament', 'http://www.wikidata.org/entity/Q501902'), ('subTournamentName', "1946 Wimbledon Championships – Men's Singles"), ('winner', 'http://www.wikidata.org/entity/Q957935'), ('winnerName', 'Yvon Petra')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q501879'), ('yearlyWimbledonTournamentName', '1946 Wimbledon Championships'), ('subTournament', 'http://www.wikidata.org/entity/Q501871'), ('subTournamentName', "1946 Wimbledon Championships – Women's Singles"), ('winner', 'http://www.wikidata.org/entity/Q53331'), ('winnerName', 'Pauline Betz')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q501884'), ('yearlyWimbledonTournamentName', '1947 Wimbledon Championships'), ('subTournament', 'http://www.wikidata.org/entity/Q501895'), ('subTournamentName', "1947 Wimbledon Championships – Men's Singles"), ('winner', 'http://www.wikidata.org/entity/Q54529'), ('winnerName', 'Jack Kramer')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q501884'), ('yearlyWimbledonTournamentName', '1947 Wimbledon Championships'), ('subTournament', 'http://www.wikidata.org/entity/Q501889'), ('subTournamentName', "1947 Wimbledon Championships – Women's Singles"), ('winner', 'http://www.wikidata.org/entity/Q53411'), ('winnerName', 'Margaret Osborne duPont')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q502011'), ('yearlyWimbledonTournamentName', '1948 Wimbledon Championships'), ('subTournament', 'http://www.wikidata.org/entity/Q502015'), ('subTournamentName', "1948 Wimbledon Championships – Men's Singles"), ('winner', 'http://www.wikidata.org/entity/Q53420'), ('winnerName', 'Bob Falkenburg')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q502011'), ('yearlyWimbledonTournamentName', '1948 Wimbledon Championships'), ('subTournament', 'http://www.wikidata.org/entity/Q502007'), ('subTournamentName', "1948 Wimbledon Championships – Women's Singles"), ('winner', 'http://www.wikidata.org/entity/Q53338'), ('winnerName', 'Louise Brough')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q612679'), ('yearlyWimbledonTournamentName', '1949 Wimbledon Championships'), ('subTournament', 'http://www.wikidata.org/entity/Q612735'), ('subTournamentName', "1949 Wimbledon Championships – Men's Singles"), ('winner', 'http://www.wikidata.org/entity/Q54580'), ('winnerName', 'Ted Schroeder')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q612679'), ('yearlyWimbledonTournamentName', '1949 Wimbledon Championships'), ('subTournament', 'http://www.wikidata.org/entity/Q612719'), ('subTournamentName', "1949 Wimbledon Championships – Women's Singles"), ('winner', 'http://www.wikidata.org/entity/Q53338'), ('winnerName', 'Louise Brough')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q613346'), ('yearlyWimbledonTournamentName', '1950 Wimbledon Championships'), ('subTournament', 'http://www.wikidata.org/entity/Q612756'), ('subTournamentName', "1950 Wimbledon Championships – Men's Singles"), ('winner', 'http://www.wikidata.org/entity/Q54549'), ('winnerName', 'Budge Patty')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q613346'), ('yearlyWimbledonTournamentName', '1950 Wimbledon Championships'), ('subTournament', 'http://www.wikidata.org/entity/Q612764'), ('subTournamentName', "1950 Wimbledon Championships – Women's Singles"), ('winner', 'http://www.wikidata.org/entity/Q53338'), ('winnerName', 'Louise Brough')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q613356'), ('yearlyWimbledonTournamentName', '1951 Wimbledon Championships'), ('subTournament', 'http://www.wikidata.org/entity/Q612747'), ('subTournamentName', "1951 Wimbledon Championships – Men's Singles"), ('winner', 'http://www.wikidata.org/entity/Q54577'), ('winnerName', 'Dick Savitt')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q613356'), ('yearlyWimbledonTournamentName', '1951 Wimbledon Championships'), ('subTournament', 'http://www.wikidata.org/entity/Q612711'), ('subTournamentName', "1951 Wimbledon Championships – Women's Singles"), ('winner', 'http://www.wikidata.org/entity/Q53564'), ('winnerName', 'Doris Hart')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q576785'), ('yearlyWimbledonTournamentName', '1952 Wimbledon Championships'), ('subTournament', 'http://www.wikidata.org/entity/Q577205'), ('subTournamentName', "1952 Wimbledon Championships – Men's Singles"), ('winner', 'http://www.wikidata.org/entity/Q962049'), ('winnerName', 'Frank Sedgman')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q576785'), ('yearlyWimbledonTournamentName', '1952 Wimbledon Championships'), ('subTournament', 'http://www.wikidata.org/entity/Q576977'), ('subTournamentName', "1952 Wimbledon Championships – Women's Singles"), ('winner', 'http://www.wikidata.org/entity/Q53390'), ('winnerName', 'Maureen Connolly')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q577168'), ('yearlyWimbledonTournamentName', '1953 Wimbledon Championships'), ('subTournament', 'http://www.wikidata.org/entity/Q576996'), ('subTournamentName', "1953 Wimbledon Championships – Men's Singles"), ('winner', 'http://www.wikidata.org/entity/Q54583'), ('winnerName', 'Vic Seixas')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q577168'), ('yearlyWimbledonTournamentName', '1953 Wimbledon Championships'), ('subTournament', 'http://www.wikidata.org/entity/Q577247'), ('subTournamentName', "1953 Wimbledon Championships – Women's Singles"), ('winner', 'http://www.wikidata.org/entity/Q53390'), ('winnerName', 'Maureen Connolly')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q577138'), ('yearlyWimbledonTournamentName', '1954 Wimbledon Championships'), ('subTournament', 'http://www.wikidata.org/entity/Q577236'), ('subTournamentName', "1954 Wimbledon Championships – Men's Singles"), ('winner', 'http://www.wikidata.org/entity/Q365518'), ('winnerName', 'Jaroslav Drobný')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q577138'), ('yearlyWimbledonTournamentName', '1954 Wimbledon Championships'), ('subTournament', 'http://www.wikidata.org/entity/Q576966'), ('subTournamentName', "1954 Wimbledon Championships – Women's Singles"), ('winner', 'http://www.wikidata.org/entity/Q53390'), ('winnerName', 'Maureen Connolly')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q655368'), ('yearlyWimbledonTournamentName', '1955 Wimbledon Championships'), ('subTournament', 'http://www.wikidata.org/entity/Q655310'), ('subTournamentName', "1955 Wimbledon Championships – Men's Singles"), ('winner', 'http://www.wikidata.org/entity/Q54686'), ('winnerName', 'Tony Trabert')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q655368'), ('yearlyWimbledonTournamentName', '1955 Wimbledon Championships'), ('subTournament', 'http://www.wikidata.org/entity/Q655025'), ('subTournamentName', "1955 Wimbledon Championships – Women's Singles"), ('winner', 'http://www.wikidata.org/entity/Q53338'), ('winnerName', 'Louise Brough')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q655378'), ('yearlyWimbledonTournamentName', '1956 Wimbledon Championships'), ('subTournament', 'http://www.wikidata.org/entity/Q1476670'), ('subTournamentName', "1956 Wimbledon Championships – Men's Doubles"), ('winner', 'http://www.wikidata.org/entity/Q162639'), ('winnerName', 'Lew Hoad')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q655378'), ('yearlyWimbledonTournamentName', '1956 Wimbledon Championships'), ('subTournament', 'http://www.wikidata.org/entity/Q1476670'), ('subTournamentName', "1956 Wimbledon Championships – Men's Doubles"), ('winner', 'http://www.wikidata.org/entity/Q312728'), ('winnerName', 'Ken Rosewall')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q655378'), ('yearlyWimbledonTournamentName', '1956 Wimbledon Championships'), ('subTournament', 'http://www.wikidata.org/entity/Q655327'), ('subTournamentName', "1956 Wimbledon Championships – Men's Singles"), ('winner', 'http://www.wikidata.org/entity/Q162639'), ('winnerName', 'Lew Hoad')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q655378'), ('yearlyWimbledonTournamentName', '1956 Wimbledon Championships'), ('subTournament', 'http://www.wikidata.org/entity/Q1667960'), ('subTournamentName', '1956 Wimbledon Championships – Mixed Doubles'), ('winner', 'http://www.wikidata.org/entity/Q53424'), ('winnerName', 'Shirley Fry')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q655378'), ('yearlyWimbledonTournamentName', '1956 Wimbledon Championships'), ('subTournament', 'http://www.wikidata.org/entity/Q1667960'), ('subTournamentName', '1956 Wimbledon Championships – Mixed Doubles'), ('winner', 'http://www.wikidata.org/entity/Q54583'), ('winnerName', 'Vic Seixas')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q655378'), ('yearlyWimbledonTournamentName', '1956 Wimbledon Championships'), ('subTournament', 'http://www.wikidata.org/entity/Q2582963'), ('subTournamentName', "1956 Wimbledon Championships – Women's Doubles"), ('winner', 'http://www.wikidata.org/entity/Q53550'), ('winnerName', 'Althea Gibson')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q655378'), ('yearlyWimbledonTournamentName', '1956 Wimbledon Championships'), ('subTournament', 'http://www.wikidata.org/entity/Q2582963'), ('subTournamentName', "1956 Wimbledon Championships – Women's Doubles"), ('winner', 'http://www.wikidata.org/entity/Q442632'), ('winnerName', 'Angela Buxton')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q655378'), ('yearlyWimbledonTournamentName', '1956 Wimbledon Championships'), ('subTournament', 'http://www.wikidata.org/entity/Q655345'), ('subTournamentName', "1956 Wimbledon Championships – Women's Singles"), ('winner', 'http://www.wikidata.org/entity/Q53424'), ('winnerName', 'Shirley Fry')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q657950'), ('yearlyWimbledonTournamentName', '1957 Wimbledon Championships'), ('subTournament', 'http://www.wikidata.org/entity/Q1275316'), ('subTournamentName', "1957 Wimbledon Championships – Men's Doubles"), ('winner', 'http://www.wikidata.org/entity/Q54549'), ('winnerName', 'Budge Patty')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q657950'), ('yearlyWimbledonTournamentName', '1957 Wimbledon Championships'), ('subTournament', 'http://www.wikidata.org/entity/Q1275316'), ('subTournamentName', "1957 Wimbledon Championships – Men's Doubles"), ('winner', 'http://www.wikidata.org/entity/Q54544'), ('winnerName', 'Gardnar Mulloy')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q657950'), ('yearlyWimbledonTournamentName', '1957 Wimbledon Championships'), ('subTournament', 'http://www.wikidata.org/entity/Q657685'), ('subTournamentName', "1957 Wimbledon Championships – Men's Singles"), ('winner', 'http://www.wikidata.org/entity/Q162639'), ('winnerName', 'Lew Hoad')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q657950'), ('yearlyWimbledonTournamentName', '1957 Wimbledon Championships'), ('subTournament', 'http://www.wikidata.org/entity/Q1397235'), ('subTournamentName', '1957 Wimbledon Championships – Mixed Doubles'), ('winner', 'http://www.wikidata.org/entity/Q53562'), ('winnerName', 'Darlene Hard')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q657950'), ('yearlyWimbledonTournamentName', '1957 Wimbledon Championships'), ('subTournament', 'http://www.wikidata.org/entity/Q1397235'), ('subTournamentName', '1957 Wimbledon Championships – Mixed Doubles'), ('winner', 'http://www.wikidata.org/entity/Q913948'), ('winnerName', 'Mervyn Rose')]
# 50

# %%
# write your queries

# Consider the tennis players born after 1975, return who won more Grand Slams and cut the result to the top-10 (the result set must be a list of triples player IRI, label and #victories).

# from task3 [('obj', 'http://www.wikidata.org/entity/Q41520'), ('objName', 'Wimbledon Championships')]
# <---P31 instance of -- Q30085309 '2018 Wimbledon Championships'
# --P527 ('has part')--> Q30098268 "2018 Wimbledon Championships – Women's Singles" --> P1346 ('winner') -->

# 1) getting all winner of yearly grand slam
queryString = """

SELECT (count(*) as ?tot){
SELECT DISTINCT ?yearlyWimbledonTournament ?yearlyWimbledonTournamentName ?subTournament ?subTournamentName ?winner ?winnerName
WHERE {
   # BACKWARD DISCOVERY
   # ?yearlyWimbledonTournament ?p wd:Q41520.
   # ?yearlyWimbledonTournament wdt:P527 ?subTournament.
   # ?subTournament wdt:P1346 ?winner.
   
   # get the label 
   # ?yearlyWimbledonTournament sc:name ?yearlyWimbledonTournamentName .
   # ?subTournament sc:name ?subTournamentName.
   # ?winner sc:name ?winnerName.
}
ORDER BY ASC (?subTournamentName)
}
LIMIT 50

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('tot', '422')]
# 1

# %%
# write your queries

# Consider the tennis players born after 1975, return who won more Grand Slams and cut the result to the top-10 (the result set must be a list of triples player IRI, label and #victories).

# from task3 [('obj', 'http://www.wikidata.org/entity/Q41520'), ('objName', 'Wimbledon Championships')]
# <---P31 instance of -- Q30085309 '2018 Wimbledon Championships'
# --P527 ('has part')--> Q30098268 "2018 Wimbledon Championships – Women's Singles" --> P1346 ('winner') -->

# 1) getting all winner of yearly grand slam
queryString = """

SELECT (count(*) as ?tot){
SELECT DISTINCT ?yearlyWimbledonTournament ?yearlyWimbledonTournamentName ?subTournament ?subTournamentName ?winner ?winnerName
WHERE {
   # BACKWARD DISCOVERY
   # ?yearlyWimbledonTournament wdt:P31 wd:Q41520.
   # ?yearlyWimbledonTournament wdt:P527 ?subTournament.
   # ?subTournament wdt:P1346 ?winner.
   
   # get the label 
   # ?yearlyWimbledonTournament sc:name ?yearlyWimbledonTournamentName .
   # ?subTournament sc:name ?subTournamentName.
   # ?winner sc:name ?winnerName.
}
ORDER BY ASC (?subTournamentName)
}
LIMIT 50

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('tot', '422')]
# 1

# %%
# 2) finding dob of the winner

# %% [markdown]
# ##### All useless queries to find dob

# %%
# write your queries

# Consider the tennis players born after 1975, return who won more Grand Slams and cut the result to the top-10 (the result set must be a list of triples player IRI, label and #victories).

# from task3 [('obj', 'http://www.wikidata.org/entity/Q41520'), ('objName', 'Wimbledon Championships')]
# <---P31 instance of -- Q30085309 '2018 Wimbledon Championships'
# --P527 ('has part')--> Q30098268 "2018 Wimbledon Championships – Women's Singles" --> P1346 ('winner') -->

# from query 5 Q5812'), ('winnerName', 'Novak Djokovic')]
# 1) getting winners dob 
queryString = """

SELECT DISTINCT ?p ?pName ?o ?oName
WHERE {
   wd:Q5812 ?p ?o .
   # get the label 
   # ?p sc:name ?pName.
   # ?o sc:name ?oName.
}
LIMIT 50

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P22'), ('pName', 'father'), ('o', 'http://www.wikidata.org/entity/Q17291202'), ('oName', 'Srdjan Djokovic')]
# [('p', 'http://www.wikidata.org/prop/direct/P25'), ('pName', 'mother'), ('o', 'http://www.wikidata.org/entity/Q17291209'), ('oName', 'Dijana Djokovic')]
# [('p', 'http://www.wikidata.org/prop/direct/P3373'), ('pName', 'sibling'), ('o', 'http://www.wikidata.org/entity/Q17291218'), ('oName', 'Djordje Djokovic')]
# [('p', 'http://www.wikidata.org/prop/direct/P734'), ('pName', 'family name'), ('o', 'http://www.wikidata.org/entity/Q21146583'), ('oName', 'Djokovic')]
# [('p', 'http://www.wikidata.org/prop/direct/P3373'), ('pName', 'sibling'), ('o', 'http://www.wikidata.org/entity/Q3597288'), ('oName', 'Marko Djokovic')]
# [('p', 'http://www.wikidata.org/prop/direct/P1050'), ('pName', 'medical condition'), ('o', 'http://www.wikidata.org/entity/Q11088'), ('oName', 'coeliac disease')]
# [('p', 'http://www.wikidata.org/prop/direct/P140'), ('pName', 'religion'), ('o', 'http://www.wikidata.org/entity/Q188814'), ('oName', 'Serbian Orthodox Church')]
# [('p', 'http://www.wikidata.org/prop/direct/P1344'), ('pName', 'participant in'), ('o', 'http://www.wikidata.org/entity/Q65242348'), ('oName', 'tennis at the 2020 Summer Olympics – mixed doubles')]
# [('p', 'http://www.wikidata.org/prop/direct/P106'), ('pName', 'occupation'), ('o', 'http://www.wikidata.org/entity/Q10833314'), ('oName', 'tennis player')]
# [('p', 'http://www.wikidata.org/prop/direct/P1412'), ('pName', 'languages spoken, written or signed'), ('o', 'http://www.wikidata.org/entity/Q150'), ('oName', 'French')]
# [('p', 'http://www.wikidata.org/prop/direct/P166'), ('pName', 'award received'), ('o', 'http://www.wikidata.org/entity/Q1517792'), ('oName', 'Order of St. Sava')]
# [('p', 'http://www.wikidata.org/prop/direct/P166'), ('pName', 'award received'), ('o', 'http://www.wikidata.org/entity/Q1808301'), ('oName', 'Laureus World Sports Award for Sportsman of the Year')]
# [('p', 'http://www.wikidata.org/prop/direct/P1344'), ('pName', 'participant in'), ('o', 'http://www.wikidata.org/entity/Q181278'), ('oName', '2020 Summer Olympics')]
# [('p', 'http://www.wikidata.org/prop/direct/P1412'), ('pName', 'languages spoken, written or signed'), ('o', 'http://www.wikidata.org/entity/Q1860'), ('oName', 'English')]
# [('p', 'http://www.wikidata.org/prop/direct/P1412'), ('pName', 'languages spoken, written or signed'), ('o', 'http://www.wikidata.org/entity/Q188'), ('oName', 'German')]
# [('p', 'http://www.wikidata.org/prop/direct/P39'), ('pName', 'position held'), ('o', 'http://www.wikidata.org/entity/Q19969187'), ('oName', 'UNICEF Goodwill Ambassador')]
# [('p', 'http://www.wikidata.org/prop/direct/P166'), ('pName', 'award received'), ('o', 'http://www.wikidata.org/entity/Q2545753'), ('oName', 'Order of the Star of Karađorđe')]
# [('p', 'http://www.wikidata.org/prop/direct/P552'), ('pName', 'handedness'), ('o', 'http://www.wikidata.org/entity/Q3039938'), ('oName', 'right-handedness')]
# [('p', 'http://www.wikidata.org/prop/direct/P741'), ('pName', 'playing hand'), ('o', 'http://www.wikidata.org/entity/Q3039938'), ('oName', 'right-handedness')]
# [('p', 'http://www.wikidata.org/prop/direct/P19'), ('pName', 'place of birth'), ('o', 'http://www.wikidata.org/entity/Q3711'), ('oName', 'Belgrade')]
# [('p', 'http://www.wikidata.org/prop/direct/P1532'), ('pName', 'country for sport'), ('o', 'http://www.wikidata.org/entity/Q403'), ('oName', 'Serbia')]
# [('p', 'http://www.wikidata.org/prop/direct/P27'), ('pName', 'country of citizenship'), ('o', 'http://www.wikidata.org/entity/Q403'), ('oName', 'Serbia')]
# [('p', 'http://www.wikidata.org/prop/direct/P551'), ('pName', 'residence'), ('o', 'http://www.wikidata.org/entity/Q45240'), ('oName', 'Monte Carlo')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('o', 'http://www.wikidata.org/entity/Q5'), ('oName', 'human')]
# [('p', 'http://www.wikidata.org/prop/direct/P1412'), ('pName', 'languages spoken, written or signed'), ('o', 'http://www.wikidata.org/entity/Q652'), ('oName', 'Italian')]
# [('p', 'http://www.wikidata.org/prop/direct/P21'), ('pName', 'sex or gender'), ('o', 'http://www.wikidata.org/entity/Q6581097'), ('oName', 'male')]
# [('p', 'http://www.wikidata.org/prop/direct/P1343'), ('pName', 'described by source'), ('o', 'http://www.wikidata.org/entity/Q67311526'), ('oName', 'Obalky knih.cz')]
# [('p', 'http://www.wikidata.org/prop/direct/P108'), ('pName', 'employer'), ('o', 'http://www.wikidata.org/entity/Q740308'), ('oName', 'UNICEF')]
# [('p', 'http://www.wikidata.org/prop/direct/P1050'), ('pName', 'medical condition'), ('o', 'http://www.wikidata.org/entity/Q84263196'), ('oName', 'COVID-19')]
# [('p', 'http://www.wikidata.org/prop/direct/P641'), ('pName', 'sport'), ('o', 'http://www.wikidata.org/entity/Q847'), ('oName', 'tennis')]
# [('p', 'http://www.wikidata.org/prop/direct/P1344'), ('pName', 'participant in'), ('o', 'http://www.wikidata.org/entity/Q8567'), ('oName', '2008 Summer Olympics')]
# [('p', 'http://www.wikidata.org/prop/direct/P1344'), ('pName', 'participant in'), ('o', 'http://www.wikidata.org/entity/Q8577'), ('oName', '2012 Summer Olympics')]
# [('p', 'http://www.wikidata.org/prop/direct/P1344'), ('pName', 'participant in'), ('o', 'http://www.wikidata.org/entity/Q8613'), ('oName', '2016 Summer Olympics')]
# [('p', 'http://www.wikidata.org/prop/direct/P103'), ('pName', 'native language'), ('o', 'http://www.wikidata.org/entity/Q9299'), ('oName', 'Serbian')]
# [('p', 'http://www.wikidata.org/prop/direct/P1412'), ('pName', 'languages spoken, written or signed'), ('o', 'http://www.wikidata.org/entity/Q9299'), ('oName', 'Serbian')]
# [('p', 'http://www.wikidata.org/prop/direct/P741'), ('pName', 'playing hand'), ('o', 'http://www.wikidata.org/entity/Q14420068'), ('oName', 'two-handed backhand')]
# [('p', 'http://www.wikidata.org/prop/direct/P2416'), ('pName', 'sports discipline competed in'), ('o', 'http://www.wikidata.org/entity/Q18123880'), ('oName', 'tennis singles')]
# [('p', 'http://www.wikidata.org/prop/direct/P2416'), ('pName', 'sports discipline competed in'), ('o', 'http://www.wikidata.org/entity/Q18123885'), ('oName', 'tennis doubles')]
# [('p', 'http://www.wikidata.org/prop/direct/P1344'), ('pName', 'participant in'), ('o', 'http://www.wikidata.org/entity/Q23747965'), ('oName', "tennis at the 2016 Summer Olympics – men's singles")]
# [('p', 'http://www.wikidata.org/prop/direct/P1344'), ('pName', 'participant in'), ('o', 'http://www.wikidata.org/entity/Q23748323'), ('oName', "tennis at the 2016 Summer Olympics – men's doubles")]
# [('p', 'http://www.wikidata.org/prop/direct/P1344'), ('pName', 'participant in'), ('o', 'http://www.wikidata.org/entity/Q374383'), ('oName', "tennis at the 2012 Summer Olympics – men's doubles")]
# [('p', 'http://www.wikidata.org/prop/direct/P1344'), ('pName', 'participant in'), ('o', 'http://www.wikidata.org/entity/Q581788'), ('oName', "tennis at the 2012 Summer Olympics – men's singles")]
# [('p', 'http://www.wikidata.org/prop/direct/P1344'), ('pName', 'participant in'), ('o', 'http://www.wikidata.org/entity/Q65242345'), ('oName', "tennis at the 2020 Summer Olympics – men's singles")]
# [('p', 'http://www.wikidata.org/prop/direct/P1344'), ('pName', 'participant in'), ('o', 'http://www.wikidata.org/entity/Q752428'), ('oName', "tennis at the 2008 Summer Olympics – men's singles")]
# [('p', 'http://www.wikidata.org/prop/direct/P1344'), ('pName', 'participant in'), ('o', 'http://www.wikidata.org/entity/Q757054'), ('oName', "tennis at the 2008 Summer Olympics – men's doubles")]
# [('p', 'http://www.wikidata.org/prop/direct/P737'), ('pName', 'influenced by'), ('o', 'http://www.wikidata.org/entity/Q7166221'), ('oName', 'Pepe Imaz')]
# [('p', 'http://www.wikidata.org/prop/direct/P737'), ('pName', 'influenced by'), ('o', 'http://www.wikidata.org/entity/Q205058'), ('oName', 'Masaru Emoto')]
# [('p', 'http://www.wikidata.org/prop/direct/P735'), ('pName', 'given name'), ('o', 'http://www.wikidata.org/entity/Q12797610'), ('oName', 'Novak')]
# [('p', 'http://www.wikidata.org/prop/direct/P741'), ('pName', 'playing hand'), ('o', 'http://www.wikidata.org/entity/Q14419931'), ('oName', 'one-handed forehand')]
# [('p', 'http://www.wikidata.org/prop/direct/P1424'), ('pName', "topic's main template"), ('o', 'http://www.wikidata.org/entity/Q11128493'), ('oName', 'Template:Novak Djokovic')]
# 50

# %%
# write your queries

# Consider the tennis players born after 1975, return who won more Grand Slams and cut the result to the top-10 (the result set must be a list of triples player IRI, label and #victories).

# from task3 [('obj', 'http://www.wikidata.org/entity/Q41520'), ('objName', 'Wimbledon Championships')]
# <---P31 instance of -- Q30085309 '2018 Wimbledon Championships'
# --P527 ('has part')--> Q30098268 "2018 Wimbledon Championships – Women's Singles" --> P1346 ('winner') -->

# from query 5 Q5812'), ('winnerName', 'Novak Djokovic')]
# 1) getting winners dob 
queryString = """

SELECT DISTINCT ?p ?pName ?o ?oName
WHERE {
   wd:Q5812 ?p ?o .
   # get the label 
   # ?p sc:name ?pName.
   # ?o sc:name ?oName.
   
   FILTER (?p != wdt:P1344)
}
LIMIT 50

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P22'), ('pName', 'father'), ('o', 'http://www.wikidata.org/entity/Q17291202'), ('oName', 'Srdjan Djokovic')]
# [('p', 'http://www.wikidata.org/prop/direct/P25'), ('pName', 'mother'), ('o', 'http://www.wikidata.org/entity/Q17291209'), ('oName', 'Dijana Djokovic')]
# [('p', 'http://www.wikidata.org/prop/direct/P3373'), ('pName', 'sibling'), ('o', 'http://www.wikidata.org/entity/Q17291218'), ('oName', 'Djordje Djokovic')]
# [('p', 'http://www.wikidata.org/prop/direct/P734'), ('pName', 'family name'), ('o', 'http://www.wikidata.org/entity/Q21146583'), ('oName', 'Djokovic')]
# [('p', 'http://www.wikidata.org/prop/direct/P3373'), ('pName', 'sibling'), ('o', 'http://www.wikidata.org/entity/Q3597288'), ('oName', 'Marko Djokovic')]
# [('p', 'http://www.wikidata.org/prop/direct/P1050'), ('pName', 'medical condition'), ('o', 'http://www.wikidata.org/entity/Q11088'), ('oName', 'coeliac disease')]
# [('p', 'http://www.wikidata.org/prop/direct/P140'), ('pName', 'religion'), ('o', 'http://www.wikidata.org/entity/Q188814'), ('oName', 'Serbian Orthodox Church')]
# [('p', 'http://www.wikidata.org/prop/direct/P106'), ('pName', 'occupation'), ('o', 'http://www.wikidata.org/entity/Q10833314'), ('oName', 'tennis player')]
# [('p', 'http://www.wikidata.org/prop/direct/P1412'), ('pName', 'languages spoken, written or signed'), ('o', 'http://www.wikidata.org/entity/Q150'), ('oName', 'French')]
# [('p', 'http://www.wikidata.org/prop/direct/P166'), ('pName', 'award received'), ('o', 'http://www.wikidata.org/entity/Q1517792'), ('oName', 'Order of St. Sava')]
# [('p', 'http://www.wikidata.org/prop/direct/P166'), ('pName', 'award received'), ('o', 'http://www.wikidata.org/entity/Q1808301'), ('oName', 'Laureus World Sports Award for Sportsman of the Year')]
# [('p', 'http://www.wikidata.org/prop/direct/P1412'), ('pName', 'languages spoken, written or signed'), ('o', 'http://www.wikidata.org/entity/Q1860'), ('oName', 'English')]
# [('p', 'http://www.wikidata.org/prop/direct/P1412'), ('pName', 'languages spoken, written or signed'), ('o', 'http://www.wikidata.org/entity/Q188'), ('oName', 'German')]
# [('p', 'http://www.wikidata.org/prop/direct/P39'), ('pName', 'position held'), ('o', 'http://www.wikidata.org/entity/Q19969187'), ('oName', 'UNICEF Goodwill Ambassador')]
# [('p', 'http://www.wikidata.org/prop/direct/P166'), ('pName', 'award received'), ('o', 'http://www.wikidata.org/entity/Q2545753'), ('oName', 'Order of the Star of Karađorđe')]
# [('p', 'http://www.wikidata.org/prop/direct/P552'), ('pName', 'handedness'), ('o', 'http://www.wikidata.org/entity/Q3039938'), ('oName', 'right-handedness')]
# [('p', 'http://www.wikidata.org/prop/direct/P741'), ('pName', 'playing hand'), ('o', 'http://www.wikidata.org/entity/Q3039938'), ('oName', 'right-handedness')]
# [('p', 'http://www.wikidata.org/prop/direct/P19'), ('pName', 'place of birth'), ('o', 'http://www.wikidata.org/entity/Q3711'), ('oName', 'Belgrade')]
# [('p', 'http://www.wikidata.org/prop/direct/P1532'), ('pName', 'country for sport'), ('o', 'http://www.wikidata.org/entity/Q403'), ('oName', 'Serbia')]
# [('p', 'http://www.wikidata.org/prop/direct/P27'), ('pName', 'country of citizenship'), ('o', 'http://www.wikidata.org/entity/Q403'), ('oName', 'Serbia')]
# [('p', 'http://www.wikidata.org/prop/direct/P551'), ('pName', 'residence'), ('o', 'http://www.wikidata.org/entity/Q45240'), ('oName', 'Monte Carlo')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('o', 'http://www.wikidata.org/entity/Q5'), ('oName', 'human')]
# [('p', 'http://www.wikidata.org/prop/direct/P1412'), ('pName', 'languages spoken, written or signed'), ('o', 'http://www.wikidata.org/entity/Q652'), ('oName', 'Italian')]
# [('p', 'http://www.wikidata.org/prop/direct/P21'), ('pName', 'sex or gender'), ('o', 'http://www.wikidata.org/entity/Q6581097'), ('oName', 'male')]
# [('p', 'http://www.wikidata.org/prop/direct/P1343'), ('pName', 'described by source'), ('o', 'http://www.wikidata.org/entity/Q67311526'), ('oName', 'Obalky knih.cz')]
# [('p', 'http://www.wikidata.org/prop/direct/P108'), ('pName', 'employer'), ('o', 'http://www.wikidata.org/entity/Q740308'), ('oName', 'UNICEF')]
# [('p', 'http://www.wikidata.org/prop/direct/P1050'), ('pName', 'medical condition'), ('o', 'http://www.wikidata.org/entity/Q84263196'), ('oName', 'COVID-19')]
# [('p', 'http://www.wikidata.org/prop/direct/P641'), ('pName', 'sport'), ('o', 'http://www.wikidata.org/entity/Q847'), ('oName', 'tennis')]
# [('p', 'http://www.wikidata.org/prop/direct/P103'), ('pName', 'native language'), ('o', 'http://www.wikidata.org/entity/Q9299'), ('oName', 'Serbian')]
# [('p', 'http://www.wikidata.org/prop/direct/P1412'), ('pName', 'languages spoken, written or signed'), ('o', 'http://www.wikidata.org/entity/Q9299'), ('oName', 'Serbian')]
# [('p', 'http://www.wikidata.org/prop/direct/P741'), ('pName', 'playing hand'), ('o', 'http://www.wikidata.org/entity/Q14420068'), ('oName', 'two-handed backhand')]
# [('p', 'http://www.wikidata.org/prop/direct/P2416'), ('pName', 'sports discipline competed in'), ('o', 'http://www.wikidata.org/entity/Q18123880'), ('oName', 'tennis singles')]
# [('p', 'http://www.wikidata.org/prop/direct/P2416'), ('pName', 'sports discipline competed in'), ('o', 'http://www.wikidata.org/entity/Q18123885'), ('oName', 'tennis doubles')]
# [('p', 'http://www.wikidata.org/prop/direct/P737'), ('pName', 'influenced by'), ('o', 'http://www.wikidata.org/entity/Q7166221'), ('oName', 'Pepe Imaz')]
# [('p', 'http://www.wikidata.org/prop/direct/P737'), ('pName', 'influenced by'), ('o', 'http://www.wikidata.org/entity/Q205058'), ('oName', 'Masaru Emoto')]
# [('p', 'http://www.wikidata.org/prop/direct/P735'), ('pName', 'given name'), ('o', 'http://www.wikidata.org/entity/Q12797610'), ('oName', 'Novak')]
# [('p', 'http://www.wikidata.org/prop/direct/P741'), ('pName', 'playing hand'), ('o', 'http://www.wikidata.org/entity/Q14419931'), ('oName', 'one-handed forehand')]
# [('p', 'http://www.wikidata.org/prop/direct/P1424'), ('pName', "topic's main template"), ('o', 'http://www.wikidata.org/entity/Q11128493'), ('oName', 'Template:Novak Djokovic')]
# [('p', 'http://www.wikidata.org/prop/direct/P286'), ('pName', 'head coach'), ('o', 'http://www.wikidata.org/entity/Q1291378'), ('oName', 'Marián Vajda')]
# [('p', 'http://www.wikidata.org/prop/direct/P26'), ('pName', 'spouse'), ('o', 'http://www.wikidata.org/entity/Q17291251'), ('oName', 'Jelena Djokovic')]
# [('p', 'http://www.wikidata.org/prop/direct/P286'), ('pName', 'head coach'), ('o', 'http://www.wikidata.org/entity/Q23039404'), ('oName', 'Riccardo Piatti')]
# [('p', 'http://www.wikidata.org/prop/direct/P166'), ('pName', 'award received'), ('o', 'http://www.wikidata.org/entity/Q33684'), ('oName', 'Order of the Republika Srpska')]
# [('p', 'http://www.wikidata.org/prop/direct/P910'), ('pName', "topic's main category"), ('o', 'http://www.wikidata.org/entity/Q7441658'), ('oName', 'Category:Novak Djokovic')]
# 43

# %%
# write your queries

# Consider the tennis players born after 1975, return who won more Grand Slams and cut the result to the top-10 (the result set must be a list of triples player IRI, label and #victories).

# from task3 [('obj', 'http://www.wikidata.org/entity/Q41520'), ('objName', 'Wimbledon Championships')]
# <---P31 instance of -- Q30085309 '2018 Wimbledon Championships'
# --P527 ('has part')--> Q30098268 "2018 Wimbledon Championships – Women's Singles" --> P1346 ('winner') -->

# from query 5 Q5812'), ('winnerName', 'Novak Djokovic')]
# 1) getting winners dob 
queryString = """

SELECT DISTINCT ?p ?pName ?o ?oName
WHERE {
   wd:Q1426 ?p ?o .
   # get the label 
   # ?p sc:name ?pName.
   # ?o sc:name ?oName.
   
   FILTER (?p != wdt:P1344)
}
LIMIT 50

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P2522'), ('pName', 'victory'), ('o', 'http://www.wikidata.org/entity/Q22956224'), ('oName', "2017 Australian Open – Men's Singles")]
# [('p', 'http://www.wikidata.org/prop/direct/P2522'), ('pName', 'victory'), ('o', 'http://www.wikidata.org/entity/Q612597'), ('oName', '2007 Tennis Masters Cup')]
# [('p', 'http://www.wikidata.org/prop/direct/P3342'), ('pName', 'significant person'), ('o', 'http://www.wikidata.org/entity/Q54584'), ('oName', 'Andy Roddick')]
# [('p', 'http://www.wikidata.org/prop/direct/P166'), ('pName', 'award received'), ('o', 'http://www.wikidata.org/entity/Q56509472'), ('oName', 'honorary doctor of the University of Basel')]
# [('p', 'http://www.wikidata.org/prop/direct/P6758'), ('pName', 'supported sports team'), ('o', 'http://www.wikidata.org/entity/Q189671'), ('oName', 'FC Basel')]
# [('p', 'http://www.wikidata.org/prop/direct/P2522'), ('pName', 'victory'), ('o', 'http://www.wikidata.org/entity/Q782589'), ('oName', "2010 Australian Open – Men's Singles")]
# [('p', 'http://www.wikidata.org/prop/direct/P2522'), ('pName', 'victory'), ('o', 'http://www.wikidata.org/entity/Q782420'), ('oName', "2006 Australian Open – Men's Singles")]
# [('p', 'http://www.wikidata.org/prop/direct/P166'), ('pName', 'award received'), ('o', 'http://www.wikidata.org/entity/Q1061233'), ('oName', "L'Équipe Champion of Champions")]
# [('p', 'http://www.wikidata.org/prop/direct/P106'), ('pName', 'occupation'), ('o', 'http://www.wikidata.org/entity/Q10833314'), ('oName', 'tennis player')]
# [('p', 'http://www.wikidata.org/prop/direct/P741'), ('pName', 'playing hand'), ('o', 'http://www.wikidata.org/entity/Q14420039'), ('oName', 'one-handed backhand')]
# [('p', 'http://www.wikidata.org/prop/direct/P1412'), ('pName', 'languages spoken, written or signed'), ('o', 'http://www.wikidata.org/entity/Q150'), ('oName', 'French')]
# [('p', 'http://www.wikidata.org/prop/direct/P1343'), ('pName', 'described by source'), ('o', 'http://www.wikidata.org/entity/Q17290934'), ('oName', 'Lentapedia')]
# [('p', 'http://www.wikidata.org/prop/direct/P1412'), ('pName', 'languages spoken, written or signed'), ('o', 'http://www.wikidata.org/entity/Q1860'), ('oName', 'English')]
# [('p', 'http://www.wikidata.org/prop/direct/P103'), ('pName', 'native language'), ('o', 'http://www.wikidata.org/entity/Q188'), ('oName', 'German')]
# [('p', 'http://www.wikidata.org/prop/direct/P1412'), ('pName', 'languages spoken, written or signed'), ('o', 'http://www.wikidata.org/entity/Q188'), ('oName', 'German')]
# [('p', 'http://www.wikidata.org/prop/direct/P39'), ('pName', 'position held'), ('o', 'http://www.wikidata.org/entity/Q19969187'), ('oName', 'UNICEF Goodwill Ambassador')]
# [('p', 'http://www.wikidata.org/prop/direct/P552'), ('pName', 'handedness'), ('o', 'http://www.wikidata.org/entity/Q3039938'), ('oName', 'right-handedness')]
# [('p', 'http://www.wikidata.org/prop/direct/P1532'), ('pName', 'country for sport'), ('o', 'http://www.wikidata.org/entity/Q39'), ('oName', 'Switzerland')]
# [('p', 'http://www.wikidata.org/prop/direct/P27'), ('pName', 'country of citizenship'), ('o', 'http://www.wikidata.org/entity/Q39'), ('oName', 'Switzerland')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('o', 'http://www.wikidata.org/entity/Q5'), ('oName', 'human')]
# [('p', 'http://www.wikidata.org/prop/direct/P21'), ('pName', 'sex or gender'), ('o', 'http://www.wikidata.org/entity/Q6581097'), ('oName', 'male')]
# [('p', 'http://www.wikidata.org/prop/direct/P1343'), ('pName', 'described by source'), ('o', 'http://www.wikidata.org/entity/Q67311526'), ('oName', 'Obalky knih.cz')]
# [('p', 'http://www.wikidata.org/prop/direct/P108'), ('pName', 'employer'), ('o', 'http://www.wikidata.org/entity/Q740308'), ('oName', 'UNICEF')]
# [('p', 'http://www.wikidata.org/prop/direct/P19'), ('pName', 'place of birth'), ('o', 'http://www.wikidata.org/entity/Q78'), ('oName', 'Basel')]
# [('p', 'http://www.wikidata.org/prop/direct/P641'), ('pName', 'sport'), ('o', 'http://www.wikidata.org/entity/Q847'), ('oName', 'tennis')]
# [('p', 'http://www.wikidata.org/prop/direct/P140'), ('pName', 'religion'), ('o', 'http://www.wikidata.org/entity/Q9592'), ('oName', 'Catholic Church')]
# [('p', 'http://www.wikidata.org/prop/direct/P2522'), ('pName', 'victory'), ('o', 'http://www.wikidata.org/entity/Q300024'), ('oName', '2011 ATP World Tour Finals')]
# [('p', 'http://www.wikidata.org/prop/direct/P2416'), ('pName', 'sports discipline competed in'), ('o', 'http://www.wikidata.org/entity/Q18123880'), ('oName', 'tennis singles')]
# [('p', 'http://www.wikidata.org/prop/direct/P2416'), ('pName', 'sports discipline competed in'), ('o', 'http://www.wikidata.org/entity/Q18123885'), ('oName', 'tennis doubles')]
# [('p', 'http://www.wikidata.org/prop/direct/P735'), ('pName', 'given name'), ('o', 'http://www.wikidata.org/entity/Q4925304'), ('oName', 'Roger')]
# [('p', 'http://www.wikidata.org/prop/direct/P166'), ('pName', 'award received'), ('o', 'http://www.wikidata.org/entity/Q338737'), ('oName', 'Swiss Sports Personality of the Year')]
# [('p', 'http://www.wikidata.org/prop/direct/P166'), ('pName', 'award received'), ('o', 'http://www.wikidata.org/entity/Q3494048'), ('oName', 'BBC Overseas Sports Personality of the Year')]
# [('p', 'http://www.wikidata.org/prop/direct/P2522'), ('pName', 'victory'), ('o', 'http://www.wikidata.org/entity/Q753300'), ('oName', "2012 Wimbledon Championships – Gentlemen's Singles")]
# [('p', 'http://www.wikidata.org/prop/direct/P2522'), ('pName', 'victory'), ('o', 'http://www.wikidata.org/entity/Q757054'), ('oName', "tennis at the 2008 Summer Olympics – men's doubles")]
# [('p', 'http://www.wikidata.org/prop/direct/P2522'), ('pName', 'victory'), ('o', 'http://www.wikidata.org/entity/Q1074654'), ('oName', "2006 Wimbledon Championships – Men's Singles")]
# [('p', 'http://www.wikidata.org/prop/direct/P2522'), ('pName', 'victory'), ('o', 'http://www.wikidata.org/entity/Q384929'), ('oName', "2005 Wimbledon Championships – Men's Singles")]
# [('p', 'http://www.wikidata.org/prop/direct/P551'), ('pName', 'residence'), ('o', 'http://www.wikidata.org/entity/Q70036'), ('oName', 'Bottmingen')]
# [('p', 'http://www.wikidata.org/prop/direct/P2522'), ('pName', 'victory'), ('o', 'http://www.wikidata.org/entity/Q14916861'), ('oName', '2014 Davis Cup')]
# [('p', 'http://www.wikidata.org/prop/direct/P741'), ('pName', 'playing hand'), ('o', 'http://www.wikidata.org/entity/Q14419931'), ('oName', 'one-handed forehand')]
# [('p', 'http://www.wikidata.org/prop/direct/P2522'), ('pName', 'victory'), ('o', 'http://www.wikidata.org/entity/Q46993124'), ('oName', "2018 Australian Open – Men's Singles")]
# [('p', 'http://www.wikidata.org/prop/direct/P166'), ('pName', 'award received'), ('o', 'http://www.wikidata.org/entity/Q4896696'), ('oName', 'Best International Athlete ESPY Award')]
# [('p', 'http://www.wikidata.org/prop/direct/P286'), ('pName', 'head coach'), ('o', 'http://www.wikidata.org/entity/Q15649219'), ('oName', 'Severin Lüthi')]
# [('p', 'http://www.wikidata.org/prop/direct/P734'), ('pName', 'family name'), ('o', 'http://www.wikidata.org/entity/Q16869916'), ('oName', 'Federer')]
# [('p', 'http://www.wikidata.org/prop/direct/P286'), ('pName', 'head coach'), ('o', 'http://www.wikidata.org/entity/Q261095'), ('oName', 'Ivan Ljubičić')]
# [('p', 'http://www.wikidata.org/prop/direct/P2522'), ('pName', 'victory'), ('o', 'http://www.wikidata.org/entity/Q964291'), ('oName', '2006 Tennis Masters Cup')]
# [('p', 'http://www.wikidata.org/prop/direct/P2522'), ('pName', 'victory'), ('o', 'http://www.wikidata.org/entity/Q300022'), ('oName', '2010 ATP World Tour Finals')]
# [('p', 'http://www.wikidata.org/prop/direct/P2522'), ('pName', 'victory'), ('o', 'http://www.wikidata.org/entity/Q1048953'), ('oName', "2004 US Open – Men's Singles")]
# [('p', 'http://www.wikidata.org/prop/direct/P2522'), ('pName', 'victory'), ('o', 'http://www.wikidata.org/entity/Q731509'), ('oName', "2005 US Open – Men's Singles")]
# [('p', 'http://www.wikidata.org/prop/direct/P2522'), ('pName', 'victory'), ('o', 'http://www.wikidata.org/entity/Q741573'), ('oName', "2009 French Open – Men's Singles")]
# [('p', 'http://www.wikidata.org/prop/direct/P2522'), ('pName', 'victory'), ('o', 'http://www.wikidata.org/entity/Q912506'), ('oName', "2006 US Open – Men's Singles")]
# 50

# %%
# write your queries

# Consider the tennis players born after 1975, return who won more Grand Slams and cut the result to the top-10 (the result set must be a list of triples player IRI, label and #victories).

# from task3 [('obj', 'http://www.wikidata.org/entity/Q41520'), ('objName', 'Wimbledon Championships')]
# <---P31 instance of -- Q30085309 '2018 Wimbledon Championships'
# --P527 ('has part')--> Q30098268 "2018 Wimbledon Championships – Women's Singles" --> P1346 ('winner') -->

# from query 5 Q5812'), ('winnerName', 'Novak Djokovic')]
# 1) getting winners dob 
queryString = """

SELECT DISTINCT ?p ?pName ?o ?oName
WHERE {
   wd:Q1426 ?p ?o .
   # get the label 
   # ?p sc:name ?pName.
   # ?o sc:name ?oName.
   
   FILTER (?p != wdt:P1344 && ?p != wdt:P2522)
}
LIMIT 50

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P103'), ('pName', 'native language'), ('o', 'http://www.wikidata.org/entity/Q188'), ('oName', 'German')]
# [('p', 'http://www.wikidata.org/prop/direct/P106'), ('pName', 'occupation'), ('o', 'http://www.wikidata.org/entity/Q10833314'), ('oName', 'tennis player')]
# [('p', 'http://www.wikidata.org/prop/direct/P108'), ('pName', 'employer'), ('o', 'http://www.wikidata.org/entity/Q740308'), ('oName', 'UNICEF')]
# [('p', 'http://www.wikidata.org/prop/direct/P1343'), ('pName', 'described by source'), ('o', 'http://www.wikidata.org/entity/Q17290934'), ('oName', 'Lentapedia')]
# [('p', 'http://www.wikidata.org/prop/direct/P1343'), ('pName', 'described by source'), ('o', 'http://www.wikidata.org/entity/Q67311526'), ('oName', 'Obalky knih.cz')]
# [('p', 'http://www.wikidata.org/prop/direct/P140'), ('pName', 'religion'), ('o', 'http://www.wikidata.org/entity/Q9592'), ('oName', 'Catholic Church')]
# [('p', 'http://www.wikidata.org/prop/direct/P1412'), ('pName', 'languages spoken, written or signed'), ('o', 'http://www.wikidata.org/entity/Q150'), ('oName', 'French')]
# [('p', 'http://www.wikidata.org/prop/direct/P1412'), ('pName', 'languages spoken, written or signed'), ('o', 'http://www.wikidata.org/entity/Q1860'), ('oName', 'English')]
# [('p', 'http://www.wikidata.org/prop/direct/P1412'), ('pName', 'languages spoken, written or signed'), ('o', 'http://www.wikidata.org/entity/Q188'), ('oName', 'German')]
# [('p', 'http://www.wikidata.org/prop/direct/P1532'), ('pName', 'country for sport'), ('o', 'http://www.wikidata.org/entity/Q39'), ('oName', 'Switzerland')]
# [('p', 'http://www.wikidata.org/prop/direct/P166'), ('pName', 'award received'), ('o', 'http://www.wikidata.org/entity/Q56509472'), ('oName', 'honorary doctor of the University of Basel')]
# [('p', 'http://www.wikidata.org/prop/direct/P166'), ('pName', 'award received'), ('o', 'http://www.wikidata.org/entity/Q1061233'), ('oName', "L'Équipe Champion of Champions")]
# [('p', 'http://www.wikidata.org/prop/direct/P166'), ('pName', 'award received'), ('o', 'http://www.wikidata.org/entity/Q338737'), ('oName', 'Swiss Sports Personality of the Year')]
# [('p', 'http://www.wikidata.org/prop/direct/P166'), ('pName', 'award received'), ('o', 'http://www.wikidata.org/entity/Q3494048'), ('oName', 'BBC Overseas Sports Personality of the Year')]
# [('p', 'http://www.wikidata.org/prop/direct/P166'), ('pName', 'award received'), ('o', 'http://www.wikidata.org/entity/Q4896696'), ('oName', 'Best International Athlete ESPY Award')]
# [('p', 'http://www.wikidata.org/prop/direct/P166'), ('pName', 'award received'), ('o', 'http://www.wikidata.org/entity/Q693708'), ('oName', 'ITF World Champions')]
# [('p', 'http://www.wikidata.org/prop/direct/P19'), ('pName', 'place of birth'), ('o', 'http://www.wikidata.org/entity/Q78'), ('oName', 'Basel')]
# [('p', 'http://www.wikidata.org/prop/direct/P21'), ('pName', 'sex or gender'), ('o', 'http://www.wikidata.org/entity/Q6581097'), ('oName', 'male')]
# [('p', 'http://www.wikidata.org/prop/direct/P22'), ('pName', 'father'), ('o', 'http://www.wikidata.org/entity/Q17291275'), ('oName', 'Robert Federer')]
# [('p', 'http://www.wikidata.org/prop/direct/P2416'), ('pName', 'sports discipline competed in'), ('o', 'http://www.wikidata.org/entity/Q18123880'), ('oName', 'tennis singles')]
# [('p', 'http://www.wikidata.org/prop/direct/P2416'), ('pName', 'sports discipline competed in'), ('o', 'http://www.wikidata.org/entity/Q18123885'), ('oName', 'tennis doubles')]
# [('p', 'http://www.wikidata.org/prop/direct/P25'), ('pName', 'mother'), ('o', 'http://www.wikidata.org/entity/Q17291278'), ('oName', 'Lynette Federer')]
# [('p', 'http://www.wikidata.org/prop/direct/P26'), ('pName', 'spouse'), ('o', 'http://www.wikidata.org/entity/Q233306'), ('oName', 'Mirka Federer')]
# [('p', 'http://www.wikidata.org/prop/direct/P27'), ('pName', 'country of citizenship'), ('o', 'http://www.wikidata.org/entity/Q39'), ('oName', 'Switzerland')]
# [('p', 'http://www.wikidata.org/prop/direct/P286'), ('pName', 'head coach'), ('o', 'http://www.wikidata.org/entity/Q15649219'), ('oName', 'Severin Lüthi')]
# [('p', 'http://www.wikidata.org/prop/direct/P286'), ('pName', 'head coach'), ('o', 'http://www.wikidata.org/entity/Q261095'), ('oName', 'Ivan Ljubičić')]
# [('p', 'http://www.wikidata.org/prop/direct/P286'), ('pName', 'head coach'), ('o', 'http://www.wikidata.org/entity/Q1348847'), ('oName', 'José Higueras')]
# [('p', 'http://www.wikidata.org/prop/direct/P286'), ('pName', 'head coach'), ('o', 'http://www.wikidata.org/entity/Q1968483'), ('oName', 'Peter Carter')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('o', 'http://www.wikidata.org/entity/Q5'), ('oName', 'human')]
# [('p', 'http://www.wikidata.org/prop/direct/P3342'), ('pName', 'significant person'), ('o', 'http://www.wikidata.org/entity/Q54584'), ('oName', 'Andy Roddick')]
# [('p', 'http://www.wikidata.org/prop/direct/P3373'), ('pName', 'sibling'), ('o', 'http://www.wikidata.org/entity/Q17291284'), ('oName', 'Dziana Federer')]
# [('p', 'http://www.wikidata.org/prop/direct/P39'), ('pName', 'position held'), ('o', 'http://www.wikidata.org/entity/Q19969187'), ('oName', 'UNICEF Goodwill Ambassador')]
# [('p', 'http://www.wikidata.org/prop/direct/P40'), ('pName', 'child'), ('o', 'http://www.wikidata.org/entity/Q17291294'), ('oName', 'Myla Federer')]
# [('p', 'http://www.wikidata.org/prop/direct/P40'), ('pName', 'child'), ('o', 'http://www.wikidata.org/entity/Q17291300'), ('oName', 'Charlene Federer')]
# [('p', 'http://www.wikidata.org/prop/direct/P40'), ('pName', 'child'), ('o', 'http://www.wikidata.org/entity/Q17291308'), ('oName', 'Leo Federer')]
# [('p', 'http://www.wikidata.org/prop/direct/P40'), ('pName', 'child'), ('o', 'http://www.wikidata.org/entity/Q17291316'), ('oName', 'Lennart Federer')]
# [('p', 'http://www.wikidata.org/prop/direct/P463'), ('pName', 'member of'), ('o', 'http://www.wikidata.org/entity/Q1675504'), ('oName', 'Swiss Tennis')]
# [('p', 'http://www.wikidata.org/prop/direct/P551'), ('pName', 'residence'), ('o', 'http://www.wikidata.org/entity/Q70036'), ('oName', 'Bottmingen')]
# [('p', 'http://www.wikidata.org/prop/direct/P552'), ('pName', 'handedness'), ('o', 'http://www.wikidata.org/entity/Q3039938'), ('oName', 'right-handedness')]
# [('p', 'http://www.wikidata.org/prop/direct/P641'), ('pName', 'sport'), ('o', 'http://www.wikidata.org/entity/Q847'), ('oName', 'tennis')]
# [('p', 'http://www.wikidata.org/prop/direct/P734'), ('pName', 'family name'), ('o', 'http://www.wikidata.org/entity/Q16869916'), ('oName', 'Federer')]
# [('p', 'http://www.wikidata.org/prop/direct/P735'), ('pName', 'given name'), ('o', 'http://www.wikidata.org/entity/Q4925304'), ('oName', 'Roger')]
# [('p', 'http://www.wikidata.org/prop/direct/P741'), ('pName', 'playing hand'), ('o', 'http://www.wikidata.org/entity/Q14420039'), ('oName', 'one-handed backhand')]
# [('p', 'http://www.wikidata.org/prop/direct/P741'), ('pName', 'playing hand'), ('o', 'http://www.wikidata.org/entity/Q14419931'), ('oName', 'one-handed forehand')]
# [('p', 'http://www.wikidata.org/prop/direct/P910'), ('pName', "topic's main category"), ('o', 'http://www.wikidata.org/entity/Q7257144'), ('oName', 'Category:Roger Federer')]
# [('p', 'http://www.wikidata.org/prop/direct/P6758'), ('pName', 'supported sports team'), ('o', 'http://www.wikidata.org/entity/Q189671'), ('oName', 'FC Basel')]
# 46

# %%
# write your queries

# Consider the tennis players born after 1975, return who won more Grand Slams and cut the result to the top-10 (the result set must be a list of triples player IRI, label and #victories).

# from task3 [('obj', 'http://www.wikidata.org/entity/Q41520'), ('objName', 'Wimbledon Championships')]
# <---P31 instance of -- Q30085309 '2018 Wimbledon Championships'
# --P527 ('has part')--> Q30098268 "2018 Wimbledon Championships – Women's Singles" --> P1346 ('winner') -->

# from query 5 Q5812'), ('winnerName', 'Novak Djokovic')]
# 1) getting winners dob 
queryString = """

SELECT DISTINCT ?p ?pName ?o ?oName
WHERE {
   wd:Q17291294 ?p ?o .
   # get the label 
   # ?p sc:name ?pName.
   # ?o sc:name ?oName.
   
   FILTER (?p != wdt:P1344 && ?p != wdt:P2522)
}
LIMIT 50

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P21'), ('pName', 'sex or gender'), ('o', 'http://www.wikidata.org/entity/Q6581072'), ('oName', 'female')]
# [('p', 'http://www.wikidata.org/prop/direct/P22'), ('pName', 'father'), ('o', 'http://www.wikidata.org/entity/Q1426'), ('oName', 'Roger Federer')]
# [('p', 'http://www.wikidata.org/prop/direct/P25'), ('pName', 'mother'), ('o', 'http://www.wikidata.org/entity/Q233306'), ('oName', 'Mirka Federer')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('o', 'http://www.wikidata.org/entity/Q5'), ('oName', 'human')]
# [('p', 'http://www.wikidata.org/prop/direct/P3373'), ('pName', 'sibling'), ('o', 'http://www.wikidata.org/entity/Q17291316'), ('oName', 'Lennart Federer')]
# [('p', 'http://www.wikidata.org/prop/direct/P3373'), ('pName', 'sibling'), ('o', 'http://www.wikidata.org/entity/Q17291300'), ('oName', 'Charlene Federer')]
# [('p', 'http://www.wikidata.org/prop/direct/P3373'), ('pName', 'sibling'), ('o', 'http://www.wikidata.org/entity/Q17291308'), ('oName', 'Leo Federer')]
# 7

# %%
# write your queries

# Consider the tennis players born after 1975, return who won more Grand Slams and cut the result to the top-10 (the result set must be a list of triples player IRI, label and #victories).

# from task3 [('obj', 'http://www.wikidata.org/entity/Q41520'), ('objName', 'Wimbledon Championships')]
# <---P31 instance of -- Q30085309 '2018 Wimbledon Championships'
# --P527 ('has part')--> Q30098268 "2018 Wimbledon Championships – Women's Singles" --> P1346 ('winner') -->

# from query 5 Q5812'), ('winnerName', 'Novak Djokovic')]
# 1) getting winners dob 
queryString = """

SELECT DISTINCT ?s ?sName ?p ?pName
WHERE {
   # ?s ?p wd:Q17291294.
   # get the label 
   # ?p sc:name ?pName.
   # ?s sc:name ?sName.
}
LIMIT 50

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('s', 'http://www.wikidata.org/entity/Q1426'), ('sName', 'Roger Federer'), ('p', 'http://www.wikidata.org/prop/direct/P40'), ('pName', 'child')]
# [('s', 'http://www.wikidata.org/entity/Q17291300'), ('sName', 'Charlene Federer'), ('p', 'http://www.wikidata.org/prop/direct/P3373'), ('pName', 'sibling')]
# [('s', 'http://www.wikidata.org/entity/Q17291308'), ('sName', 'Leo Federer'), ('p', 'http://www.wikidata.org/prop/direct/P3373'), ('pName', 'sibling')]
# [('s', 'http://www.wikidata.org/entity/Q17291316'), ('sName', 'Lennart Federer'), ('p', 'http://www.wikidata.org/prop/direct/P3373'), ('pName', 'sibling')]
# [('s', 'http://www.wikidata.org/entity/Q233306'), ('sName', 'Mirka Federer'), ('p', 'http://www.wikidata.org/prop/direct/P40'), ('pName', 'child')]
# 5

# %%
# write your queries

# Consider the tennis players born after 1975, return who won more Grand Slams and cut the result to the top-10 (the result set must be a list of triples player IRI, label and #victories).

# from task3 [('obj', 'http://www.wikidata.org/entity/Q41520'), ('objName', 'Wimbledon Championships')]
# <---P31 instance of -- Q30085309 '2018 Wimbledon Championships'
# --P527 ('has part')--> Q30098268 "2018 Wimbledon Championships – Women's Singles" --> P1346 ('winner') -->

# from query 5 Q5812'), ('winnerName', 'Novak Djokovic')]
# 1) getting winners dob 
queryString = """

SELECT DISTINCT ?s ?sName ?p ?pName
WHERE {
   # ?s ?p wd:Q1426.
   # get the label 
   # ?p sc:name ?pName.
   # ?s sc:name ?sName.
}
LIMIT 50

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('s', 'http://www.wikidata.org/entity/Q22956224'), ('sName', "2017 Australian Open – Men's Singles"), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner')]
# [('s', 'http://www.wikidata.org/entity/Q3983549'), ('sName', '2007 Tennis Masters Cup – singles'), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner')]
# [('s', 'http://www.wikidata.org/entity/Q2537671'), ('sName', '2011 Qatar Open – singles'), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner')]
# [('s', 'http://www.wikidata.org/entity/Q13076407'), ('sName', "2012 Mutua Madrid Open – Men's Singles"), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner')]
# [('s', 'http://www.wikidata.org/entity/Q30311438'), ('sName', '2017 Gerry Weber Open – singles'), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner')]
# [('s', 'http://www.wikidata.org/entity/Q3633911'), ('sName', '2005 Western & Southern Financial Group Masters – singles'), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner')]
# [('s', 'http://www.wikidata.org/entity/Q54584'), ('sName', 'Andy Roddick'), ('p', 'http://www.wikidata.org/prop/direct/P3342'), ('pName', 'significant person')]
# [('s', 'http://www.wikidata.org/entity/Q782589'), ('sName', "2010 Australian Open – Men's Singles"), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner')]
# [('s', 'http://www.wikidata.org/entity/Q58363'), ('sName', "2006 NASDAQ-100 Open – Men's Singles"), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner')]
# [('s', 'http://www.wikidata.org/entity/Q3720084'), ('sName', 'Nick Kyrgios'), ('p', 'http://www.wikidata.org/prop/direct/P737'), ('pName', 'influenced by')]
# [('s', 'http://www.wikidata.org/entity/Q782420'), ('sName', "2006 Australian Open – Men's Singles"), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner')]
# [('s', 'http://www.wikidata.org/entity/Q1808301'), ('sName', 'Laureus World Sports Award for Sportsman of the Year'), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner')]
# [('s', 'http://www.wikidata.org/entity/Q3816928'), ('sName', "2002 Kremlin Cup – Men's Doubles"), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner')]
# [('s', 'http://www.wikidata.org/entity/Q4601774'), ('sName', '2003 Roger Federer tennis season'), ('p', 'http://www.wikidata.org/prop/direct/P1269'), ('pName', 'facet of')]
# [('s', 'http://www.wikidata.org/entity/Q23766780'), ('sName', '2016 Monte-Carlo Rolex Masters – singles'), ('p', 'http://www.wikidata.org/prop/direct/P710'), ('pName', 'participant')]
# [('s', 'http://www.wikidata.org/entity/Q28869949'), ('sName', "2017 BNP Paribas Open – Men's Singles"), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner')]
# [('s', 'http://www.wikidata.org/entity/Q33092'), ('sName', '2008 Gerry Weber Open – singles'), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner')]
# [('s', 'http://www.wikidata.org/entity/Q3494048'), ('sName', 'BBC Overseas Sports Personality of the Year'), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner')]
# [('s', 'http://www.wikidata.org/entity/Q753300'), ('sName', "2012 Wimbledon Championships – Gentlemen's Singles"), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner')]
# [('s', 'http://www.wikidata.org/entity/Q757054'), ('sName', "tennis at the 2008 Summer Olympics – men's doubles"), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner')]
# [('s', 'http://www.wikidata.org/entity/Q1074654'), ('sName', "2006 Wimbledon Championships – Men's Singles"), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner')]
# [('s', 'http://www.wikidata.org/entity/Q384929'), ('sName', "2005 Wimbledon Championships – Men's Singles"), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner')]
# [('s', 'http://www.wikidata.org/entity/Q15666697'), ('sName', '2014 Roger Federer tennis season'), ('p', 'http://www.wikidata.org/prop/direct/P1269'), ('pName', 'facet of')]
# [('s', 'http://www.wikidata.org/entity/Q33458'), ('sName', '2005 Gerry Weber Open – singles'), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner')]
# [('s', 'http://www.wikidata.org/entity/Q1644845'), ('sName', '2005 Qatar Open – singles'), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner')]
# [('s', 'http://www.wikidata.org/entity/Q3634285'), ('sName', '2003 CA-TennisTrophy – singles'), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner')]
# [('s', 'http://www.wikidata.org/entity/Q16983050'), ('sName', '2014 Gerry Weber Open – singles'), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner')]
# [('s', 'http://www.wikidata.org/entity/Q18336310'), ('sName', '2014 Swiss Indoors – singles'), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner')]
# [('s', 'http://www.wikidata.org/entity/Q3869381'), ('sName', "2003 NASDAQ-100 Open – Men's Doubles"), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner')]
# [('s', 'http://www.wikidata.org/entity/Q4612261'), ('sName', "2008 Wimbledon Championships – Men's Singles final"), ('p', 'http://www.wikidata.org/prop/direct/P710'), ('pName', 'participant')]
# [('s', 'http://www.wikidata.org/entity/Q4629801'), ('sName', '2013 Roger Federer tennis season'), ('p', 'http://www.wikidata.org/prop/direct/P1269'), ('pName', 'facet of')]
# [('s', 'http://www.wikidata.org/entity/Q3703751'), ('sName', '2008 Davidoff Swiss Indoors – singles'), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner')]
# [('s', 'http://www.wikidata.org/entity/P536'), ('sName', 'ATP player ID'), ('p', 'http://www.wikidata.org/prop/direct/P1855'), ('pName', 'Wikidata property example')]
# [('s', 'http://www.wikidata.org/entity/Q58465'), ('sName', "2005 NASDAQ-100 Open – Men's Singles"), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner')]
# [('s', 'http://www.wikidata.org/entity/P555'), ('sName', 'doubles record'), ('p', 'http://www.wikidata.org/prop/direct/P1855'), ('pName', 'Wikidata property example')]
# [('s', 'http://www.wikidata.org/entity/Q13423423'), ('sName', '2013 Gerry Weber Open – singles'), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner')]
# [('s', 'http://www.wikidata.org/entity/Q2613138'), ('sName', "2012 Dubai Tennis Championships – Men's Singles"), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner')]
# [('s', 'http://www.wikidata.org/entity/Q1648328'), ('sName', '2006 Rogers Masters – singles'), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner')]
# [('s', 'http://www.wikidata.org/entity/P6308'), ('sName', 'Scoresway tennis person ID'), ('p', 'http://www.wikidata.org/prop/direct/P1855'), ('pName', 'Wikidata property example')]
# [('s', 'http://www.wikidata.org/entity/Q336862'), ('sName', 'Guido Pella'), ('p', 'http://www.wikidata.org/prop/direct/P737'), ('pName', 'influenced by')]
# [('s', 'http://www.wikidata.org/entity/Q20088951'), ('sName', '2015 Gerry Weber Open – singles'), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner')]
# [('s', 'http://www.wikidata.org/entity/Q4622262'), ('sName', '2011 Roger Federer tennis season'), ('p', 'http://www.wikidata.org/prop/direct/P1269'), ('pName', 'facet of')]
# [('s', 'http://www.wikidata.org/entity/Q20745019'), ('sName', 'Luca Margaroli'), ('p', 'http://www.wikidata.org/prop/direct/P737'), ('pName', 'influenced by')]
# [('s', 'http://www.wikidata.org/entity/Q46993124'), ('sName', "2018 Australian Open – Men's Singles"), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner')]
# [('s', 'http://www.wikidata.org/entity/Q47501368'), ('sName', '2018 Roger Federer tennis season'), ('p', 'http://www.wikidata.org/prop/direct/P1269'), ('pName', 'facet of')]
# [('s', 'http://www.wikidata.org/entity/Q47501368'), ('sName', '2018 Roger Federer tennis season'), ('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of')]
# [('s', 'http://www.wikidata.org/entity/Q775304'), ('sName', "2002 Adidas International – Men's Singles"), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner')]
# [('s', 'http://www.wikidata.org/entity/Q54813043'), ('sName', 'Lorenzo Musetti'), ('p', 'http://www.wikidata.org/prop/direct/P737'), ('pName', 'influenced by')]
# [('s', 'http://www.wikidata.org/entity/Q4896696'), ('sName', 'Best International Athlete ESPY Award'), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner')]
# [('s', 'http://www.wikidata.org/entity/Q4896731'), ('sName', 'Best Male Tennis Player ESPY Award'), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner')]
# 50

# %%
# write your queries

# Consider the tennis players born after 1975, return who won more Grand Slams and cut the result to the top-10 (the result set must be a list of triples player IRI, label and #victories).

# from task3 [('obj', 'http://www.wikidata.org/entity/Q41520'), ('objName', 'Wimbledon Championships')]
# <---P31 instance of -- Q30085309 '2018 Wimbledon Championships'
# --P527 ('has part')--> Q30098268 "2018 Wimbledon Championships – Women's Singles" --> P1346 ('winner') -->

# from query 5 Q5812'), ('winnerName', 'Novak Djokovic')]
# 1) getting winners dob 
queryString = """

SELECT DISTINCT ?s ?sName ?p ?pName
WHERE {
   # ?s ?p wd:Q30085309.
   # get the label 
   # ?p sc:name ?pName.
   # ?s sc:name ?sName.
}
LIMIT 50

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('s', 'http://www.wikidata.org/entity/Q30098268'), ('sName', "2018 Wimbledon Championships – Women's Singles"), ('p', 'http://www.wikidata.org/prop/direct/P361'), ('pName', 'part of')]
# [('s', 'http://www.wikidata.org/entity/Q25344121'), ('sName', '2017 Wimbledon Championships'), ('p', 'http://www.wikidata.org/prop/direct/P156'), ('pName', 'followed by')]
# [('s', 'http://www.wikidata.org/entity/Q32358401'), ('sName', '2018 Wimbledon Championships – Mixed Doubles'), ('p', 'http://www.wikidata.org/prop/direct/P361'), ('pName', 'part of')]
# [('s', 'http://www.wikidata.org/entity/Q55639017'), ('sName', '2018 Wimbledon Championships – Wheelchair Quad Doubles'), ('p', 'http://www.wikidata.org/prop/direct/P361'), ('pName', 'part of')]
# [('s', 'http://www.wikidata.org/entity/Q55455418'), ('sName', "2018 Wimbledon Championships – Wheelchair Men's Doubles"), ('p', 'http://www.wikidata.org/prop/direct/P361'), ('pName', 'part of')]
# [('s', 'http://www.wikidata.org/entity/Q54093953'), ('sName', '2019 Wimbledon Championships'), ('p', 'http://www.wikidata.org/prop/direct/P155'), ('pName', 'follows')]
# [('s', 'http://www.wikidata.org/entity/Q32357790'), ('sName', "2018 Wimbledon Championships – Men's Doubles"), ('p', 'http://www.wikidata.org/prop/direct/P361'), ('pName', 'part of')]
# [('s', 'http://www.wikidata.org/entity/Q53582240'), ('sName', 'Category:2018 Wimbledon Championships'), ('p', 'http://www.wikidata.org/prop/direct/P301'), ('pName', "category's main topic")]
# [('s', 'http://www.wikidata.org/entity/Q32356704'), ('sName', "2018 Wimbledon Championships – Women's Doubles"), ('p', 'http://www.wikidata.org/prop/direct/P361'), ('pName', 'part of')]
# [('s', 'http://www.wikidata.org/entity/Q55381839'), ('sName', "2018 Wimbledon Championships – Girls' Singles"), ('p', 'http://www.wikidata.org/prop/direct/P361'), ('pName', 'part of')]
# [('s', 'http://www.wikidata.org/entity/Q54961494'), ('sName', "2018 Wimbledon Championships – Men's Singles"), ('p', 'http://www.wikidata.org/prop/direct/P361'), ('pName', 'part of')]
# [('s', 'http://www.wikidata.org/entity/Q55410290'), ('sName', "2018 Wimbledon Championships – Girls' Doubles"), ('p', 'http://www.wikidata.org/prop/direct/P361'), ('pName', 'part of')]
# [('s', 'http://www.wikidata.org/entity/Q55410361'), ('sName', "2018 Wimbledon Championships – Boys' Doubles"), ('p', 'http://www.wikidata.org/prop/direct/P361'), ('pName', 'part of')]
# [('s', 'http://www.wikidata.org/entity/Q55455404'), ('sName', "2018 Wimbledon Championships – Wheelchair Women's Singles"), ('p', 'http://www.wikidata.org/prop/direct/P361'), ('pName', 'part of')]
# [('s', 'http://www.wikidata.org/entity/Q55455410'), ('sName', "2018 Wimbledon Championships – Wheelchair Men's Singles"), ('p', 'http://www.wikidata.org/prop/direct/P361'), ('pName', 'part of')]
# [('s', 'http://www.wikidata.org/entity/Q55381833'), ('sName', "2018 Wimbledon Championships – Boys' Singles"), ('p', 'http://www.wikidata.org/prop/direct/P361'), ('pName', 'part of')]
# [('s', 'http://www.wikidata.org/entity/Q55455423'), ('sName', "2018 Wimbledon Championships – Wheelchair Women's Doubles"), ('p', 'http://www.wikidata.org/prop/direct/P361'), ('pName', 'part of')]
# 17

# %%
# write your queries

# Consider the tennis players born after 1975, return who won more Grand Slams and cut the result to the top-10 (the result set must be a list of triples player IRI, label and #victories).

# from task3 [('obj', 'http://www.wikidata.org/entity/Q41520'), ('objName', 'Wimbledon Championships')]
# <---P31 instance of -- Q30085309 '2018 Wimbledon Championships'
# --P527 ('has part')--> Q30098268 "2018 Wimbledon Championships – Women's Singles" --> P1346 ('winner') -->

# from query 5 Q5812'), ('winnerName', 'Novak Djokovic')]
# 1) getting winners dob 
queryString = """

SELECT DISTINCT ?s ?sName ?p ?pName
WHERE {
   # ?s ?p wd:Q5.
   # get the label 
   # ?p sc:name ?pName.
   # ?s sc:name ?sName.
}
LIMIT 50

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('s', 'http://www.wikidata.org/entity/Q1002728'), ('sName', 'Fonsi Nieto'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q100343342'), ('sName', 'Lubomír Stoklásek'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q102115260'), ('sName', 'Kojiro Kobayashi'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q102118153'), ('sName', 'Miguel E. M. Herrera'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q105753880'), ('sName', 'Mateo Egea'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q107520918'), ('sName', 'Jerónimo Latorre'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q11404285'), ('sName', 'Mikiko Kitano'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q11520274'), ('sName', 'Honjō Fusanaga'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q11562694'), ('sName', 'Takayoshi Watanabe'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q11685026'), ('sName', 'Joan de Gènova'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q11686949'), ('sName', 'José Ximénez'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q11871976'), ('sName', 'Klaus Wirzenius'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q1342082'), ('sName', 'Youssef Ziedan'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q1370907'), ('sName', 'Empress Dowager Longyu'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q1373516'), ('sName', 'Eugénio de Castro'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q15215818'), ('sName', 'Erzsébet Bereczky'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q15523196'), ('sName', 'Felix Hormuth'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q15628796'), ('sName', 'Pedro Ponce de Cabrera'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q17215040'), ('sName', 'Tsutsui Junsei'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q17413490'), ('sName', 'Antón Patiño Regueira'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q18531652'), ('sName', 'William Walker'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q19594453'), ('sName', 'Menchu Lamas'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q20100600'), ('sName', 'Antoni Freixa i Martí'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q23415658'), ('sName', 'Farhad Rachidi'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q23581262'), ('sName', 'Miguel Avellán'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q2397814'), ('sName', 'Bernard Ogilvie Dodge'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q240377'), ('sName', 'Amanda Palmer'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q242964'), ('sName', 'Sophie Evans'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q259758'), ('sName', 'Andrés Mendoza'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q28475249'), ('sName', 'Joaquín Garrigues Díaz-Cañabate'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q294840'), ('sName', 'Polycrates'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q30346830'), ('sName', 'Carlos Lamela'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q3047923'), ('sName', 'Edmond Maître'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q310715'), ('sName', 'Henri Fantin-Latour'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q3108675'), ('sName', 'Glen Ennis'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q3179763'), ('sName', 'Joaquín Garrigues Walker'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q3191192'), ('sName', 'Júlia Lopes de Almeida'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q328722'), ('sName', 'Sebastián Durón'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q3430855'), ('sName', 'Richard Hazard'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q3753720'), ('sName', 'Julia Álvarez Resano'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q3818317'), ('sName', 'Roger Casamajor'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q3900876'), ('sName', 'Peter Kocher'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q4093892'), ('sName', 'Petr Ivanovich Borisov'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q4247367'), ('sName', 'Jari Kuokkanen'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q44098402'), ('sName', 'Emilio Garrigues'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q456991'), ('sName', 'Pablo Gargallo'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q465556'), ('sName', 'Annie Ilonzeh'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q4723046'), ('sName', 'Alfred Laubin'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q4749659'), ('sName', 'Amós Salvador Rodrigáñez'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q509360'), ('sName', 'Prince Gong'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# 50

# %%
# write your queries

# Consider the tennis players born after 1975, return who won more Grand Slams and cut the result to the top-10 (the result set must be a list of triples player IRI, label and #victories).

# from task3 [('obj', 'http://www.wikidata.org/entity/Q41520'), ('objName', 'Wimbledon Championships')]
# <---P31 instance of -- Q30085309 '2018 Wimbledon Championships'
# --P527 ('has part')--> Q30098268 "2018 Wimbledon Championships – Women's Singles" --> P1346 ('winner') -->

# from query 5 Q5812'), ('winnerName', 'Novak Djokovic')]
# 1) getting winners dob 
queryString = """

SELECT DISTINCT ?p ?pName ?o ?oName
WHERE {
   wd:Q5 ?p ?o .
   # get the label 
   # ?p sc:name ?pName.
   # ?o sc:name ?oName.
}
LIMIT 50

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('o', 'http://www.wikidata.org/entity/P1317'), ('oName', 'floruit')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('o', 'http://www.wikidata.org/entity/P1477'), ('oName', 'birth name')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('o', 'http://www.wikidata.org/entity/P1559'), ('oName', 'name in native language')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('o', 'http://www.wikidata.org/entity/P509'), ('oName', 'cause of death')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('o', 'http://www.wikidata.org/entity/P3373'), ('oName', 'sibling')]
# [('p', 'http://www.wikidata.org/prop/direct/P1552'), ('pName', 'has quality'), ('o', 'http://www.wikidata.org/entity/Q785260'), ('oName', 'phase of human life')]
# [('p', 'http://www.wikidata.org/prop/direct/P1889'), ('pName', 'different from'), ('o', 'http://www.wikidata.org/entity/Q95074'), ('oName', 'fictional character')]
# [('p', 'http://www.wikidata.org/prop/direct/P2579'), ('pName', 'studied by'), ('o', 'http://www.wikidata.org/entity/Q23404'), ('oName', 'anthropology')]
# [('p', 'http://www.wikidata.org/prop/direct/P1552'), ('pName', 'has quality'), ('o', 'http://www.wikidata.org/entity/Q3769299'), ('oName', 'human behavior')]
# [('p', 'http://www.wikidata.org/prop/direct/P361'), ('pName', 'part of'), ('o', 'http://www.wikidata.org/entity/Q8425'), ('oName', 'society')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('o', 'http://www.wikidata.org/entity/P119'), ('oName', 'place of burial')]
# [('p', 'http://www.wikidata.org/prop/direct/P1889'), ('pName', 'different from'), ('o', 'http://www.wikidata.org/entity/Q215627'), ('oName', 'person')]
# [('p', 'http://www.wikidata.org/prop/direct/P2670'), ('pName', 'has parts of the class'), ('o', 'http://www.wikidata.org/entity/Q215627'), ('oName', 'person')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q215627'), ('oName', 'person')]
# [('p', 'http://www.wikidata.org/prop/direct/P1552'), ('pName', 'has quality'), ('o', 'http://www.wikidata.org/entity/Q1071027'), ('oName', 'personal name')]
# [('p', 'http://www.wikidata.org/prop/direct/P5869'), ('pName', 'model item'), ('o', 'http://www.wikidata.org/entity/Q762'), ('oName', 'Leonardo da Vinci')]
# [('p', 'http://www.wikidata.org/prop/direct/P1552'), ('pName', 'has quality'), ('o', 'http://www.wikidata.org/entity/Q3307505'), ('oName', 'sociality')]
# [('p', 'http://www.wikidata.org/prop/direct/P5869'), ('pName', 'model item'), ('o', 'http://www.wikidata.org/entity/Q1043'), ('oName', 'Carl Linnaeus')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('o', 'http://www.wikidata.org/entity/P937'), ('oName', 'work location')]
# [('p', 'http://www.wikidata.org/prop/direct/P1552'), ('pName', 'has quality'), ('o', 'http://www.wikidata.org/entity/Q641118'), ('oName', 'personality')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('o', 'http://www.wikidata.org/entity/P101'), ('oName', 'field of work')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('o', 'http://www.wikidata.org/entity/P140'), ('oName', 'religion')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('o', 'http://www.wikidata.org/entity/P18'), ('oName', 'image')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('o', 'http://www.wikidata.org/entity/P25'), ('oName', 'mother')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('o', 'http://www.wikidata.org/entity/P26'), ('oName', 'spouse')]
# [('p', 'http://www.wikidata.org/prop/direct/P1343'), ('pName', 'described by source'), ('o', 'http://www.wikidata.org/entity/Q19180675'), ('oName', 'Small Brockhaus and Efron Encyclopedic Dictionary')]
# [('p', 'http://www.wikidata.org/prop/direct/P129'), ('pName', 'physically interacts with'), ('o', 'http://www.wikidata.org/entity/Q2'), ('oName', 'Earth')]
# [('p', 'http://www.wikidata.org/prop/direct/P1552'), ('pName', 'has quality'), ('o', 'http://www.wikidata.org/entity/Q223642'), ('oName', 'interpersonal relationship')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('o', 'http://www.wikidata.org/entity/Q23852'), ('oName', 'human body')]
# [('p', 'http://www.wikidata.org/prop/direct/P1343'), ('pName', 'described by source'), ('o', 'http://www.wikidata.org/entity/Q302556'), ('oName', 'Catholic Encyclopedia')]
# [('p', 'http://www.wikidata.org/prop/direct/P2283'), ('pName', 'uses'), ('o', 'http://www.wikidata.org/entity/Q39546'), ('oName', 'tool')]
# [('p', 'http://www.wikidata.org/prop/direct/P1343'), ('pName', 'described by source'), ('o', 'http://www.wikidata.org/entity/Q4086271'), ('oName', 'Bible Encyclopedia of Archimandrite Nicephorus')]
# [('p', 'http://www.wikidata.org/prop/direct/P1343'), ('pName', 'described by source'), ('o', 'http://www.wikidata.org/entity/Q4173137'), ('oName', 'Jewish Encyclopedia of Brockhaus and Efron')]
# [('p', 'http://www.wikidata.org/prop/direct/P5869'), ('pName', 'model item'), ('o', 'http://www.wikidata.org/entity/Q42'), ('oName', 'Douglas Adams')]
# [('p', 'http://www.wikidata.org/prop/direct/P1343'), ('pName', 'described by source'), ('o', 'http://www.wikidata.org/entity/Q4532138'), ('oName', 'Granat Encyclopedic Dictionary')]
# [('p', 'http://www.wikidata.org/prop/direct/P5008'), ('pName', 'on focus list of Wikimedia project'), ('o', 'http://www.wikidata.org/entity/Q5460604'), ('oName', 'Wikipedia:Vital articles')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('o', 'http://www.wikidata.org/entity/Q55983715'), ('oName', 'organisms known by a particular common name')]
# [('p', 'http://www.wikidata.org/prop/direct/P1343'), ('pName', 'described by source'), ('o', 'http://www.wikidata.org/entity/Q602358'), ('oName', 'Brockhaus and Efron Encyclopedic Dictionary')]
# [('p', 'http://www.wikidata.org/prop/direct/P5869'), ('pName', 'model item'), ('o', 'http://www.wikidata.org/entity/Q7186'), ('oName', 'Marie Curie')]
# [('p', 'http://www.wikidata.org/prop/direct/P2579'), ('pName', 'studied by'), ('o', 'http://www.wikidata.org/entity/Q720858'), ('oName', 'human ecology')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('o', 'http://www.wikidata.org/entity/P2048'), ('oName', 'height')]
# [('p', 'http://www.wikidata.org/prop/direct/P460'), ('pName', 'said to be the same as'), ('o', 'http://www.wikidata.org/entity/Q15978631'), ('oName', 'Homo sapiens')]
# [('p', 'http://www.wikidata.org/prop/direct/P1889'), ('pName', 'different from'), ('o', 'http://www.wikidata.org/entity/Q2472587'), ('oName', 'people')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('o', 'http://www.wikidata.org/entity/P39'), ('oName', 'position held')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('o', 'http://www.wikidata.org/entity/P172'), ('oName', 'ethnic group')]
# [('p', 'http://www.wikidata.org/prop/direct/P910'), ('pName', "topic's main category"), ('o', 'http://www.wikidata.org/entity/Q4047087'), ('oName', 'Category:People')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q154954'), ('oName', 'natural person')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('o', 'http://www.wikidata.org/entity/P3342'), ('oName', 'significant person')]
# [('p', 'http://www.wikidata.org/prop/direct/P361'), ('pName', 'part of'), ('o', 'http://www.wikidata.org/entity/Q42762'), ('oName', 'biosphere')]
# [('p', 'http://www.wikidata.org/prop/direct/P5869'), ('pName', 'model item'), ('o', 'http://www.wikidata.org/entity/Q43527'), ('oName', 'Sitting Bull')]
# 50

# %%
# write your queries

# Consider the tennis players born after 1975, return who won more Grand Slams and cut the result to the top-10 (the result set must be a list of triples player IRI, label and #victories).

# from task3 [('obj', 'http://www.wikidata.org/entity/Q41520'), ('objName', 'Wimbledon Championships')]
# <---P31 instance of -- Q30085309 '2018 Wimbledon Championships'
# --P527 ('has part')--> Q30098268 "2018 Wimbledon Championships – Women's Singles" --> P1346 ('winner') -->

# from query 5 Q5812'), ('winnerName', 'Novak Djokovic')]
# 1) getting winners dob 
queryString = """

SELECT DISTINCT ?p ?pName ?o ?oName
WHERE {
   wd:Q5 ?p ?o .
   # get the label 
   # ?p sc:name ?pName.
   # ?o sc:name ?oName.
}
LIMIT 100

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('o', 'http://www.wikidata.org/entity/P1317'), ('oName', 'floruit')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('o', 'http://www.wikidata.org/entity/P1477'), ('oName', 'birth name')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('o', 'http://www.wikidata.org/entity/P1559'), ('oName', 'name in native language')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('o', 'http://www.wikidata.org/entity/P509'), ('oName', 'cause of death')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('o', 'http://www.wikidata.org/entity/P3373'), ('oName', 'sibling')]
# [('p', 'http://www.wikidata.org/prop/direct/P1552'), ('pName', 'has quality'), ('o', 'http://www.wikidata.org/entity/Q785260'), ('oName', 'phase of human life')]
# [('p', 'http://www.wikidata.org/prop/direct/P1889'), ('pName', 'different from'), ('o', 'http://www.wikidata.org/entity/Q95074'), ('oName', 'fictional character')]
# [('p', 'http://www.wikidata.org/prop/direct/P2579'), ('pName', 'studied by'), ('o', 'http://www.wikidata.org/entity/Q23404'), ('oName', 'anthropology')]
# [('p', 'http://www.wikidata.org/prop/direct/P1552'), ('pName', 'has quality'), ('o', 'http://www.wikidata.org/entity/Q3769299'), ('oName', 'human behavior')]
# [('p', 'http://www.wikidata.org/prop/direct/P361'), ('pName', 'part of'), ('o', 'http://www.wikidata.org/entity/Q8425'), ('oName', 'society')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('o', 'http://www.wikidata.org/entity/P119'), ('oName', 'place of burial')]
# [('p', 'http://www.wikidata.org/prop/direct/P1889'), ('pName', 'different from'), ('o', 'http://www.wikidata.org/entity/Q215627'), ('oName', 'person')]
# [('p', 'http://www.wikidata.org/prop/direct/P2670'), ('pName', 'has parts of the class'), ('o', 'http://www.wikidata.org/entity/Q215627'), ('oName', 'person')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q215627'), ('oName', 'person')]
# [('p', 'http://www.wikidata.org/prop/direct/P1552'), ('pName', 'has quality'), ('o', 'http://www.wikidata.org/entity/Q1071027'), ('oName', 'personal name')]
# [('p', 'http://www.wikidata.org/prop/direct/P5869'), ('pName', 'model item'), ('o', 'http://www.wikidata.org/entity/Q762'), ('oName', 'Leonardo da Vinci')]
# [('p', 'http://www.wikidata.org/prop/direct/P1552'), ('pName', 'has quality'), ('o', 'http://www.wikidata.org/entity/Q3307505'), ('oName', 'sociality')]
# [('p', 'http://www.wikidata.org/prop/direct/P5869'), ('pName', 'model item'), ('o', 'http://www.wikidata.org/entity/Q1043'), ('oName', 'Carl Linnaeus')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('o', 'http://www.wikidata.org/entity/P937'), ('oName', 'work location')]
# [('p', 'http://www.wikidata.org/prop/direct/P1552'), ('pName', 'has quality'), ('o', 'http://www.wikidata.org/entity/Q641118'), ('oName', 'personality')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('o', 'http://www.wikidata.org/entity/P101'), ('oName', 'field of work')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('o', 'http://www.wikidata.org/entity/P140'), ('oName', 'religion')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('o', 'http://www.wikidata.org/entity/P18'), ('oName', 'image')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('o', 'http://www.wikidata.org/entity/P25'), ('oName', 'mother')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('o', 'http://www.wikidata.org/entity/P26'), ('oName', 'spouse')]
# [('p', 'http://www.wikidata.org/prop/direct/P1343'), ('pName', 'described by source'), ('o', 'http://www.wikidata.org/entity/Q19180675'), ('oName', 'Small Brockhaus and Efron Encyclopedic Dictionary')]
# [('p', 'http://www.wikidata.org/prop/direct/P129'), ('pName', 'physically interacts with'), ('o', 'http://www.wikidata.org/entity/Q2'), ('oName', 'Earth')]
# [('p', 'http://www.wikidata.org/prop/direct/P1552'), ('pName', 'has quality'), ('o', 'http://www.wikidata.org/entity/Q223642'), ('oName', 'interpersonal relationship')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('o', 'http://www.wikidata.org/entity/Q23852'), ('oName', 'human body')]
# [('p', 'http://www.wikidata.org/prop/direct/P1343'), ('pName', 'described by source'), ('o', 'http://www.wikidata.org/entity/Q302556'), ('oName', 'Catholic Encyclopedia')]
# [('p', 'http://www.wikidata.org/prop/direct/P2283'), ('pName', 'uses'), ('o', 'http://www.wikidata.org/entity/Q39546'), ('oName', 'tool')]
# [('p', 'http://www.wikidata.org/prop/direct/P1343'), ('pName', 'described by source'), ('o', 'http://www.wikidata.org/entity/Q4086271'), ('oName', 'Bible Encyclopedia of Archimandrite Nicephorus')]
# [('p', 'http://www.wikidata.org/prop/direct/P1343'), ('pName', 'described by source'), ('o', 'http://www.wikidata.org/entity/Q4173137'), ('oName', 'Jewish Encyclopedia of Brockhaus and Efron')]
# [('p', 'http://www.wikidata.org/prop/direct/P5869'), ('pName', 'model item'), ('o', 'http://www.wikidata.org/entity/Q42'), ('oName', 'Douglas Adams')]
# [('p', 'http://www.wikidata.org/prop/direct/P1343'), ('pName', 'described by source'), ('o', 'http://www.wikidata.org/entity/Q4532138'), ('oName', 'Granat Encyclopedic Dictionary')]
# [('p', 'http://www.wikidata.org/prop/direct/P5008'), ('pName', 'on focus list of Wikimedia project'), ('o', 'http://www.wikidata.org/entity/Q5460604'), ('oName', 'Wikipedia:Vital articles')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('o', 'http://www.wikidata.org/entity/Q55983715'), ('oName', 'organisms known by a particular common name')]
# [('p', 'http://www.wikidata.org/prop/direct/P1343'), ('pName', 'described by source'), ('o', 'http://www.wikidata.org/entity/Q602358'), ('oName', 'Brockhaus and Efron Encyclopedic Dictionary')]
# [('p', 'http://www.wikidata.org/prop/direct/P5869'), ('pName', 'model item'), ('o', 'http://www.wikidata.org/entity/Q7186'), ('oName', 'Marie Curie')]
# [('p', 'http://www.wikidata.org/prop/direct/P2579'), ('pName', 'studied by'), ('o', 'http://www.wikidata.org/entity/Q720858'), ('oName', 'human ecology')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('o', 'http://www.wikidata.org/entity/P2048'), ('oName', 'height')]
# [('p', 'http://www.wikidata.org/prop/direct/P460'), ('pName', 'said to be the same as'), ('o', 'http://www.wikidata.org/entity/Q15978631'), ('oName', 'Homo sapiens')]
# [('p', 'http://www.wikidata.org/prop/direct/P1889'), ('pName', 'different from'), ('o', 'http://www.wikidata.org/entity/Q2472587'), ('oName', 'people')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('o', 'http://www.wikidata.org/entity/P39'), ('oName', 'position held')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('o', 'http://www.wikidata.org/entity/P172'), ('oName', 'ethnic group')]
# [('p', 'http://www.wikidata.org/prop/direct/P910'), ('pName', "topic's main category"), ('o', 'http://www.wikidata.org/entity/Q4047087'), ('oName', 'Category:People')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q154954'), ('oName', 'natural person')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('o', 'http://www.wikidata.org/entity/P3342'), ('oName', 'significant person')]
# [('p', 'http://www.wikidata.org/prop/direct/P361'), ('pName', 'part of'), ('o', 'http://www.wikidata.org/entity/Q42762'), ('oName', 'biosphere')]
# [('p', 'http://www.wikidata.org/prop/direct/P5869'), ('pName', 'model item'), ('o', 'http://www.wikidata.org/entity/Q43527'), ('oName', 'Sitting Bull')]
# [('p', 'http://www.wikidata.org/prop/direct/P129'), ('pName', 'physically interacts with'), ('o', 'http://www.wikidata.org/entity/Q43619'), ('oName', 'natural environment')]
# [('p', 'http://www.wikidata.org/prop/direct/P2283'), ('pName', 'uses'), ('o', 'http://www.wikidata.org/entity/Q8205328'), ('oName', 'artificial physical object')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('o', 'http://www.wikidata.org/entity/P1813'), ('oName', 'short name')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('o', 'http://www.wikidata.org/entity/P2067'), ('oName', 'mass')]
# [('p', 'http://www.wikidata.org/prop/direct/P1552'), ('pName', 'has quality'), ('o', 'http://www.wikidata.org/entity/Q48277'), ('oName', 'gender')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('o', 'http://www.wikidata.org/entity/P21'), ('oName', 'sex or gender')]
# [('p', 'http://www.wikidata.org/prop/direct/P129'), ('pName', 'physically interacts with'), ('o', 'http://www.wikidata.org/entity/Q8195619'), ('oName', 'human food')]
# [('p', 'http://www.wikidata.org/prop/direct/P425'), ('pName', 'field of this occupation'), ('o', 'http://www.wikidata.org/entity/Q61788060'), ('oName', 'human activity')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('o', 'http://www.wikidata.org/entity/P1412'), ('oName', 'languages spoken, written or signed')]
# [('p', 'http://www.wikidata.org/prop/direct/P1552'), ('pName', 'has quality'), ('o', 'http://www.wikidata.org/entity/Q1314553'), ('oName', 'self-awareness')]
# [('p', 'http://www.wikidata.org/prop/direct/P1424'), ('pName', "topic's main template"), ('o', 'http://www.wikidata.org/entity/Q6249834'), ('oName', 'Template:Infobox person')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('o', 'http://www.wikidata.org/entity/P551'), ('oName', 'residence')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('o', 'http://www.wikidata.org/entity/P737'), ('oName', 'influenced by')]
# [('p', 'http://www.wikidata.org/prop/direct/P5869'), ('pName', 'model item'), ('o', 'http://www.wikidata.org/entity/Q7226'), ('oName', 'Joan of Arc')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('o', 'http://www.wikidata.org/entity/P19'), ('oName', 'place of birth')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('o', 'http://www.wikidata.org/entity/P569'), ('oName', 'date of birth')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('o', 'http://www.wikidata.org/entity/P570'), ('oName', 'date of death')]
# [('p', 'http://www.wikidata.org/prop/direct/P5869'), ('pName', 'model item'), ('o', 'http://www.wikidata.org/entity/Q635'), ('oName', 'Cleopatra')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('o', 'http://www.wikidata.org/entity/P20'), ('oName', 'place of death')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('o', 'http://www.wikidata.org/entity/P22'), ('oName', 'father')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('o', 'http://www.wikidata.org/entity/P40'), ('oName', 'child')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('o', 'http://www.wikidata.org/entity/P463'), ('oName', 'member of')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('o', 'http://www.wikidata.org/entity/P102'), ('oName', 'member of political party')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('o', 'http://www.wikidata.org/entity/P108'), ('oName', 'employer')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('o', 'http://www.wikidata.org/entity/P4602'), ('oName', 'date of burial or cremation')]
# [('p', 'http://www.wikidata.org/prop/direct/P1542'), ('pName', 'has effect'), ('o', 'http://www.wikidata.org/entity/Q16686448'), ('oName', 'artificial entity')]
# [('p', 'http://www.wikidata.org/prop/direct/P4733'), ('pName', 'produced sound'), ('o', 'http://www.wikidata.org/entity/Q7390'), ('oName', 'voice')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('o', 'http://www.wikidata.org/entity/P1050'), ('oName', 'medical condition')]
# [('p', 'http://www.wikidata.org/prop/direct/P5869'), ('pName', 'model item'), ('o', 'http://www.wikidata.org/entity/Q37151'), ('oName', 'Sun Tzu')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('o', 'http://www.wikidata.org/entity/P106'), ('oName', 'occupation')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('o', 'http://www.wikidata.org/entity/P1449'), ('oName', 'nickname')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('o', 'http://www.wikidata.org/entity/P734'), ('oName', 'family name')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('o', 'http://www.wikidata.org/entity/P735'), ('oName', 'given name')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('o', 'http://www.wikidata.org/entity/P742'), ('oName', 'pseudonym')]
# [('p', 'http://www.wikidata.org/prop/direct/P910'), ('pName', "topic's main category"), ('o', 'http://www.wikidata.org/entity/Q6697530'), ('oName', 'Category:Humans')]
# [('p', 'http://www.wikidata.org/prop/direct/P1424'), ('pName', "topic's main template"), ('o', 'http://www.wikidata.org/entity/Q20829728'), ('oName', 'Template:Infobox Biography2')]
# [('p', 'http://www.wikidata.org/prop/direct/P361'), ('pName', 'part of'), ('o', 'http://www.wikidata.org/entity/Q1156970'), ('oName', 'humanity')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('o', 'http://www.wikidata.org/entity/P27'), ('oName', 'country of citizenship')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('o', 'http://www.wikidata.org/entity/P103'), ('oName', 'native language')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('o', 'http://www.wikidata.org/entity/P1196'), ('oName', 'manner of death')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('o', 'http://www.wikidata.org/entity/P1576'), ('oName', 'lifestyle')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('o', 'http://www.wikidata.org/entity/P1636'), ('oName', 'date of baptism in early childhood')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('o', 'http://www.wikidata.org/entity/P451'), ('oName', 'unmarried partner')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('o', 'http://www.wikidata.org/entity/P8258'), ('oName', 'field of training')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q164509'), ('oName', 'omnivore')]
# [('p', 'http://www.wikidata.org/prop/direct/P1424'), ('pName', "topic's main template"), ('o', 'http://www.wikidata.org/entity/Q17534637'), ('oName', 'Template:Infobox person/Wikidata')]
# [('p', 'http://www.wikidata.org/prop/direct/P1552'), ('pName', 'has quality'), ('o', 'http://www.wikidata.org/entity/Q18387795'), ('oName', 'perspective-taking')]
# [('p', 'http://www.wikidata.org/prop/direct/P1552'), ('pName', 'has quality'), ('o', 'http://www.wikidata.org/entity/Q238372'), ('oName', 'Self-consciousness')]
# [('p', 'http://www.wikidata.org/prop/direct/P1552'), ('pName', 'has quality'), ('o', 'http://www.wikidata.org/entity/Q3577052'), ('oName', "person's age")]
# [('p', 'http://www.wikidata.org/prop/direct/P1056'), ('pName', 'product or material produced'), ('o', 'http://www.wikidata.org/entity/Q3619132'), ('oName', 'artefact')]
# 100

# %%
# write your queries

# Consider the tennis players born after 1975, return who won more Grand Slams and cut the result to the top-10 (the result set must be a list of triples player IRI, label and #victories).

# from task3 [('obj', 'http://www.wikidata.org/entity/Q41520'), ('objName', 'Wimbledon Championships')]
# <---P31 instance of -- Q30085309 '2018 Wimbledon Championships'
# --P527 ('has part')--> Q30098268 "2018 Wimbledon Championships – Women's Singles" --> P1346 ('winner') -->

# from query 5 Q5812'), ('winnerName', 'Novak Djokovic')]
# 1) getting winners dob 

#[('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('o', 'http://www.wikidata.org/entity/P569'), ('oName', 'date of birth')]
queryString = """

SELECT DISTINCT ?p ?pName ?o ?oName
WHERE {
   wd:Q5 wdt:P569 ?o .
   # get the label 
   # ?p sc:name ?pName.
   # ?o sc:name ?oName.
}
LIMIT 100

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# Empty

# %%
# write your queries

# Consider the tennis players born after 1975, return who won more Grand Slams and cut the result to the top-10 (the result set must be a list of triples player IRI, label and #victories).

# from task3 [('obj', 'http://www.wikidata.org/entity/Q41520'), ('objName', 'Wimbledon Championships')]
# <---P31 instance of -- Q30085309 '2018 Wimbledon Championships'
# --P527 ('has part')--> Q30098268 "2018 Wimbledon Championships – Women's Singles" --> P1346 ('winner') -->

# from query 5 Q5812'), ('winnerName', 'Novak Djokovic')]
# 1) getting winners dob 

#[('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('o', 'http://www.wikidata.org/entity/P569'), ('oName', 'date of birth')]
queryString = """

SELECT DISTINCT ?s ?sName ?o ?oName
WHERE {
   # ?s wdt:P569 ?o .
   # get the label 
   # ?s sc:name ?sName.
   # ?o sc:name ?oName.
}
LIMIT 100

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# Empty

# %%
# write your queries

# Consider the tennis players born after 1975, return who won more Grand Slams and cut the result to the top-10 (the result set must be a list of triples player IRI, label and #victories).

# from task3 [('obj', 'http://www.wikidata.org/entity/Q41520'), ('objName', 'Wimbledon Championships')]
# <---P31 instance of -- Q30085309 '2018 Wimbledon Championships'
# --P527 ('has part')--> Q30098268 "2018 Wimbledon Championships – Women's Singles" --> P1346 ('winner') -->

# from query 5 Q5812'), ('winnerName', 'Novak Djokovic')]
# 1) getting winners dob 

#[('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('o', 'http://www.wikidata.org/entity/P569'), ('oName', 'date of birth')]
queryString = """

SELECT DISTINCT ?s ?sName ?o ?oName
WHERE {
   # ?s wdt:P527 ?o .
   # get the label 
   # ?s sc:name ?sName.
   # ?o sc:name ?oName.
}
LIMIT 100

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('s', 'http://www.wikidata.org/entity/Q8200834'), ('sName', 'Anthriel'), ('o', 'http://www.wikidata.org/entity/Q11871976'), ('oName', 'Klaus Wirzenius')]
# [('s', 'http://www.wikidata.org/entity/Q4570176'), ('sName', '1960s in Hong Kong'), ('o', 'http://www.wikidata.org/entity/Q15907987'), ('oName', '1963 in Hong Kong')]
# [('s', 'http://www.wikidata.org/entity/Q4570176'), ('sName', '1960s in Hong Kong'), ('o', 'http://www.wikidata.org/entity/Q15925049'), ('oName', '1962 in Hong Kong')]
# [('s', 'http://www.wikidata.org/entity/Q661481'), ('sName', '800s BC'), ('o', 'http://www.wikidata.org/entity/Q1640473'), ('oName', '809 BC')]
# [('s', 'http://www.wikidata.org/entity/Q4619163'), ('sName', '2010s in Angola'), ('o', 'http://www.wikidata.org/entity/Q18109238'), ('oName', '2013 in Angola')]
# [('s', 'http://www.wikidata.org/entity/Q8231071'), ('sName', 'Category:Alberta provincial highways'), ('o', 'http://www.wikidata.org/entity/Q28043697'), ('oName', 'Category:Alberta provincial highways, 500–986 series')]
# [('s', 'http://www.wikidata.org/entity/Q272023'), ('sName', '830s'), ('o', 'http://www.wikidata.org/entity/Q30381'), ('oName', '834')]
# [('s', 'http://www.wikidata.org/entity/Q15974883'), ('sName', 'border of Albania'), ('o', 'http://www.wikidata.org/entity/Q3088684'), ('oName', 'Albania–Montenegro border')]
# [('s', 'http://www.wikidata.org/entity/Q8200834'), ('sName', 'Anthriel'), ('o', 'http://www.wikidata.org/entity/Q4247367'), ('oName', 'Jari Kuokkanen')]
# [('s', 'http://www.wikidata.org/entity/Q2856219'), ('sName', 'GATEPAC'), ('o', 'http://www.wikidata.org/entity/Q8179956'), ('oName', 'A. C. Documentos de Actividad Contemporánea')]
# [('s', 'http://www.wikidata.org/entity/Q1114794'), ('sName', "Grey's Anatomy, season 1"), ('o', 'http://www.wikidata.org/entity/Q8183269'), ('oName', "A Hard Day's Night")]
# [('s', 'http://www.wikidata.org/entity/Q8231071'), ('sName', 'Category:Alberta provincial highways'), ('o', 'http://www.wikidata.org/entity/Q8231026'), ('oName', 'Category:Alberta provincial highways, 1–216 series')]
# [('s', 'http://www.wikidata.org/entity/Q28043697'), ('sName', 'Category:Alberta provincial highways, 500–986 series'), ('o', 'http://www.wikidata.org/entity/Q8231027'), ('oName', 'Category:Alberta provincial highways, 900 sub-series')]
# [('s', 'http://www.wikidata.org/entity/Q1114794'), ('sName', "Grey's Anatomy, season 1"), ('o', 'http://www.wikidata.org/entity/Q9086804'), ('oName', 'The First Cut Is the Deepest')]
# [('s', 'http://www.wikidata.org/entity/Q8426039'), ('sName', "Six gentlemen of the Hundred Days' Reform"), ('o', 'http://www.wikidata.org/entity/Q11063885'), ('oName', 'Kang Youpu')]
# [('s', 'http://www.wikidata.org/entity/Q102151145'), ('sName', 'Four Sisters of Hofei'), ('o', 'http://www.wikidata.org/entity/Q11066521'), ('oName', 'Zhang Yunhe')]
# [('s', 'http://www.wikidata.org/entity/Q102151145'), ('sName', 'Four Sisters of Hofei'), ('o', 'http://www.wikidata.org/entity/Q11066524'), ('oName', 'Zhang Yuanhe')]
# [('s', 'http://www.wikidata.org/entity/Q102151145'), ('sName', 'Four Sisters of Hofei'), ('o', 'http://www.wikidata.org/entity/Q11068126'), ('oName', 'Zhang Zhaohe')]
# [('s', 'http://www.wikidata.org/entity/Q8426039'), ('sName', "Six gentlemen of the Hundred Days' Reform"), ('o', 'http://www.wikidata.org/entity/Q11118678'), ('oName', 'Yang Shenxiu')]
# [('s', 'http://www.wikidata.org/entity/Q8426039'), ('sName', "Six gentlemen of the Hundred Days' Reform"), ('o', 'http://www.wikidata.org/entity/Q11119383'), ('oName', 'Yang Rui')]
# [('s', 'http://www.wikidata.org/entity/Q8426039'), ('sName', "Six gentlemen of the Hundred Days' Reform"), ('o', 'http://www.wikidata.org/entity/Q1191225'), ('oName', 'Tan Sitong')]
# [('s', 'http://www.wikidata.org/entity/Q19577'), ('sName', 'actinide'), ('o', 'http://www.wikidata.org/entity/Q1896'), ('oName', 'fermium')]
# [('s', 'http://www.wikidata.org/entity/Q4884092'), ('sName', 'border of the Czech Republic'), ('o', 'http://www.wikidata.org/entity/Q1992001'), ('oName', 'Czech Republic–Poland border')]
# [('s', 'http://www.wikidata.org/entity/Q8350481'), ('sName', 'Convent of La Merced in Cuenca'), ('o', 'http://www.wikidata.org/entity/Q56726472'), ('oName', 'Church of La Merced')]
# [('s', 'http://www.wikidata.org/entity/Q8426039'), ('sName', "Six gentlemen of the Hundred Days' Reform"), ('o', 'http://www.wikidata.org/entity/Q6143494'), ('oName', 'Lin Xu')]
# [('s', 'http://www.wikidata.org/entity/Q8426039'), ('sName', "Six gentlemen of the Hundred Days' Reform"), ('o', 'http://www.wikidata.org/entity/Q6150494'), ('oName', 'Liu Guangdi')]
# [('s', 'http://www.wikidata.org/entity/Q8350468'), ('sName', 'Monastery of Santa Cruz la Real, Segovia'), ('o', 'http://www.wikidata.org/entity/Q64029590'), ('oName', 'Church of Monastery of Santa Cruz la Real')]
# [('s', 'http://www.wikidata.org/entity/Q8430447'), ('sName', 'Category:Exegesis'), ('o', 'http://www.wikidata.org/entity/Q7180702'), ('oName', 'Category:Quranic exegesis scholars')]
# [('s', 'http://www.wikidata.org/entity/Q7371494'), ('sName', 'Route 5'), ('o', 'http://www.wikidata.org/entity/Q8424198'), ('oName', 'Lai Chi Kok Road')]
# [('s', 'http://www.wikidata.org/entity/Q10865979'), ('sName', 'sanshi'), ('o', 'http://www.wikidata.org/entity/Q8427117'), ('oName', 'taifu')]
# [('s', 'http://www.wikidata.org/entity/Q102151145'), ('sName', 'Four Sisters of Hofei'), ('o', 'http://www.wikidata.org/entity/Q8463086'), ('oName', "Chang Ch'ung-ho")]
# [('s', 'http://www.wikidata.org/entity/Q8661147'), ('sName', '2013 Grand Prix Hassan II'), ('o', 'http://www.wikidata.org/entity/Q10745152'), ('oName', '2013 Grand Prix Hassan II – singles')]
# [('s', 'http://www.wikidata.org/entity/Q3336916'), ('sName', 'National Pan-Hellenic Council'), ('o', 'http://www.wikidata.org/entity/Q3351976'), ('oName', 'Omega Psi Phi')]
# [('s', 'http://www.wikidata.org/entity/Q8693083'), ('sName', 'auricular muscle'), ('o', 'http://www.wikidata.org/entity/Q665030'), ('oName', 'anterior auricular muscle')]
# [('s', 'http://www.wikidata.org/entity/Q8693083'), ('sName', 'auricular muscle'), ('o', 'http://www.wikidata.org/entity/Q923875'), ('oName', 'superior auricular muscle')]
# [('s', 'http://www.wikidata.org/entity/Q8693083'), ('sName', 'auricular muscle'), ('o', 'http://www.wikidata.org/entity/Q926216'), ('oName', 'posterior auricular muscle')]
# [('s', 'http://www.wikidata.org/entity/Q13656567'), ('sName', 'Genesis'), ('o', 'http://www.wikidata.org/entity/Q1009201'), ('oName', 'Genesis I')]
# [('s', 'http://www.wikidata.org/entity/Q3061434'), ('sName', 'Law & Order: Special Victims Unit, season 4'), ('o', 'http://www.wikidata.org/entity/Q13632733'), ('oName', 'Fallacy')]
# [('s', 'http://www.wikidata.org/entity/Q3336916'), ('sName', 'National Pan-Hellenic Council'), ('o', 'http://www.wikidata.org/entity/Q13638390'), ('oName', 'Iota Phi Theta')]
# [('s', 'http://www.wikidata.org/entity/Q3061434'), ('sName', 'Law & Order: Special Victims Unit, season 4'), ('o', 'http://www.wikidata.org/entity/Q13638543'), ('oName', 'Futility')]
# [('s', 'http://www.wikidata.org/entity/Q3061434'), ('sName', 'Law & Order: Special Victims Unit, season 4'), ('o', 'http://www.wikidata.org/entity/Q13647805'), ('oName', 'Grief')]
# [('s', 'http://www.wikidata.org/entity/Q13445050'), ('sName', '2013 Budapest Grand Prix'), ('o', 'http://www.wikidata.org/entity/Q13659908'), ('oName', '2013 Budapest Grand Prix – singles')]
# [('s', 'http://www.wikidata.org/entity/Q13649311'), ('sName', 'Ming Cult'), ('o', 'http://www.wikidata.org/entity/Q28950663'), ('oName', 'Heavenly Eagle Cult')]
# [('s', 'http://www.wikidata.org/entity/Q13656567'), ('sName', 'Genesis'), ('o', 'http://www.wikidata.org/entity/Q3045815'), ('oName', 'Genesis II')]
# [('s', 'http://www.wikidata.org/entity/Q13647633'), ('sName', 'Greenfield & Cook'), ('o', 'http://www.wikidata.org/entity/Q61745941'), ('oName', 'Peter Kok')]
# [('s', 'http://www.wikidata.org/entity/Q63436512'), ('sName', 'The Harry Simeone Chorale'), ('o', 'http://www.wikidata.org/entity/Q15461714'), ('oName', 'Harry Simeone')]
# [('s', 'http://www.wikidata.org/entity/Q66053233'), ('sName', 'Churches of the Pskov School of Architecture'), ('o', 'http://www.wikidata.org/entity/Q15465087'), ('oName', 'Saints Michael and Gabriel Church s Gorodtsa')]
# [('s', 'http://www.wikidata.org/entity/Q3133080'), ('sName', 'Józef and Wiktoria Ulma'), ('o', 'http://www.wikidata.org/entity/Q15477989'), ('oName', 'Józef Ulma')]
# [('s', 'http://www.wikidata.org/entity/Q15295724'), ('sName', "2014 ITF Women's Circuit"), ('o', 'http://www.wikidata.org/entity/Q15487484'), ('oName', "2014 ITF Women's Circuit (July–September)")]
# [('s', 'http://www.wikidata.org/entity/Q15462145'), ('sName', 'black pudding'), ('o', 'http://www.wikidata.org/entity/Q909834'), ('oName', 'beaten egg whites')]
# [('s', 'http://www.wikidata.org/entity/Q3133080'), ('sName', 'Józef and Wiktoria Ulma'), ('o', 'http://www.wikidata.org/entity/Q9374220'), ('oName', 'Wiktoria Ulma')]
# [('s', 'http://www.wikidata.org/entity/Q5255155'), ('sName', 'Demephion'), ('o', 'http://www.wikidata.org/entity/Q15722789'), ('oName', 'demephion-O')]
# [('s', 'http://www.wikidata.org/entity/Q3729305'), ('sName', 'My Little Pony: Friendship Is Magic, season 3'), ('o', 'http://www.wikidata.org/entity/Q15723614'), ('oName', 'Magic Duel')]
# [('s', 'http://www.wikidata.org/entity/Q3729305'), ('sName', 'My Little Pony: Friendship Is Magic, season 3'), ('o', 'http://www.wikidata.org/entity/Q15723673'), ('oName', 'One Bad Apple')]
# [('s', 'http://www.wikidata.org/entity/Q3729305'), ('sName', 'My Little Pony: Friendship Is Magic, season 3'), ('o', 'http://www.wikidata.org/entity/Q15723714'), ('oName', 'Too Many Pinkie Pies')]
# [('s', 'http://www.wikidata.org/entity/Q13646556'), ('sName', 'Grande Fratello'), ('o', 'http://www.wikidata.org/entity/Q15727770'), ('oName', 'Grande Fratello, season 13')]
# [('s', 'http://www.wikidata.org/entity/Q105834871'), ('sName', "Chelsea's (UK band) albums in chronological order"), ('o', 'http://www.wikidata.org/entity/Q15729078'), ('oName', 'Chelsea')]
# [('s', 'http://www.wikidata.org/entity/Q15729802'), ('sName', '2014 State Bank of India ATP Challenger Tour'), ('o', 'http://www.wikidata.org/entity/Q15729813'), ('oName', '2014 State Bank of India ATP Challenger Tour – doubles')]
# [('s', 'http://www.wikidata.org/entity/Q11989678'), ('sName', 'Mjøsmuseet'), ('o', 'http://www.wikidata.org/entity/Q15730205'), ('oName', 'Eiktunet')]
# [('s', 'http://www.wikidata.org/entity/Q17989090'), ('sName', 'Wake Up, Girls!'), ('o', 'http://www.wikidata.org/entity/Q15731360'), ('oName', 'Mayu Yoshioka')]
# [('s', 'http://www.wikidata.org/entity/Q15728786'), ('sName', 'Feroz Award'), ('o', 'http://www.wikidata.org/entity/Q15731913'), ('oName', 'Premio Feroz for Best Main Actor')]
# [('s', 'http://www.wikidata.org/entity/Q15728786'), ('sName', 'Feroz Award'), ('o', 'http://www.wikidata.org/entity/Q15735989'), ('oName', 'Premio Feroz for Best Supporting Actress')]
# [('s', 'http://www.wikidata.org/entity/Q9339507'), ('sName', 'Sonnets from the Crimea'), ('o', 'http://www.wikidata.org/entity/Q15737197'), ('oName', 'The Tempest')]
# [('s', 'http://www.wikidata.org/entity/Q15735956'), ('sName', '2014 Asian Junior Badminton Championships'), ('o', 'http://www.wikidata.org/entity/Q15741854'), ('oName', "2014 Asian Junior Badminton Championships – men's singles")]
# [('s', 'http://www.wikidata.org/entity/Q55234649'), ('sName', 'Transactions of the Institution of Mining and Metallurgy'), ('o', 'http://www.wikidata.org/entity/Q15746641'), ('oName', 'Transactions of the Institution of Mining and Metallurgy Section B-Applied Earth Science')]
# [('s', 'http://www.wikidata.org/entity/Q55234649'), ('sName', 'Transactions of the Institution of Mining and Metallurgy'), ('o', 'http://www.wikidata.org/entity/Q15757717'), ('oName', 'Institutions of Mining and Metallurgy. Transactions. Section C: Mineral Processing and Extractive Metallurgy')]
# [('s', 'http://www.wikidata.org/entity/Q28126629'), ('sName', 'Studies in History and Philosophy of Science'), ('o', 'http://www.wikidata.org/entity/Q15767253'), ('oName', 'Studies in History and Philosophy of Science Part A')]
# [('s', 'http://www.wikidata.org/entity/Q15732344'), ('sName', '2014 Abierto Mexicano Telcel'), ('o', 'http://www.wikidata.org/entity/Q15781322'), ('oName', '2014 Abierto Mexicano Telcel (women)')]
# [('s', 'http://www.wikidata.org/entity/Q15732344'), ('sName', '2014 Abierto Mexicano Telcel'), ('o', 'http://www.wikidata.org/entity/Q15781323'), ('oName', '2014 Abierto Mexicano Telcel (men)')]
# [('s', 'http://www.wikidata.org/entity/Q15728786'), ('sName', 'Feroz Award'), ('o', 'http://www.wikidata.org/entity/Q15818260'), ('oName', 'Premio Feroz for Best Trailer')]
# [('s', 'http://www.wikidata.org/entity/Q15728786'), ('sName', 'Feroz Award'), ('o', 'http://www.wikidata.org/entity/Q15818265'), ('oName', 'Premio Feroz for Best Film Poster')]
# [('s', 'http://www.wikidata.org/entity/Q15728786'), ('sName', 'Feroz Award'), ('o', 'http://www.wikidata.org/entity/Q15818266'), ('oName', 'Premio Feroz for Best Original Soundtrack')]
# [('s', 'http://www.wikidata.org/entity/Q15724988'), ('sName', 'Bohemian'), ('o', 'http://www.wikidata.org/entity/Q16177125'), ('oName', 'Kim Yong Jin')]
# [('s', 'http://www.wikidata.org/entity/Q15740599'), ('sName', '2014 Bucharest Open'), ('o', 'http://www.wikidata.org/entity/Q17328239'), ('oName', '2014 BRD Bucharest Open – singles')]
# [('s', 'http://www.wikidata.org/entity/Q15740599'), ('sName', '2014 Bucharest Open'), ('o', 'http://www.wikidata.org/entity/Q17328261'), ('oName', '2014 BRD Bucharest Open – doubles')]
# [('s', 'http://www.wikidata.org/entity/Q389'), ('sName', 'Andrew and variants'), ('o', 'http://www.wikidata.org/entity/Q22808327'), ('oName', 'Andriejus')]
# [('s', 'http://www.wikidata.org/entity/Q389'), ('sName', 'Andrew and variants'), ('o', 'http://www.wikidata.org/entity/Q28044955'), ('oName', 'Anndra')]
# [('s', 'http://www.wikidata.org/entity/Q15728786'), ('sName', 'Feroz Award'), ('o', 'http://www.wikidata.org/entity/Q28128436'), ('oName', 'Premio Feroz for Best Drama Series')]
# [('s', 'http://www.wikidata.org/entity/Q15728786'), ('sName', 'Feroz Award'), ('o', 'http://www.wikidata.org/entity/Q28128438'), ('oName', 'Premio Feroz for Best Main Actor in a TV Series')]
# [('s', 'http://www.wikidata.org/entity/Q15728786'), ('sName', 'Feroz Award'), ('o', 'http://www.wikidata.org/entity/Q28128439'), ('oName', 'Premio Feroz for Best Main Actress in a TV Series')]
# [('s', 'http://www.wikidata.org/entity/Q15728786'), ('sName', 'Feroz Award'), ('o', 'http://www.wikidata.org/entity/Q28128442'), ('oName', 'Premio Feroz for Best Supporting Actress in a TV Series')]
# [('s', 'http://www.wikidata.org/entity/Q15731300'), ('sName', 'Power Rangers Dino Charge'), ('o', 'http://www.wikidata.org/entity/Q65167413'), ('oName', 'Power Rangers Dino Super Charge')]
# [('s', 'http://www.wikidata.org/entity/Q15741948'), ('sName', '1956 South African Badminton Championships'), ('o', 'http://www.wikidata.org/entity/Q65687749'), ('oName', "1956 South Africa Badminton Championships – men's doubles")]
# [('s', 'http://www.wikidata.org/entity/Q15741953'), ('sName', '1958 South African Badminton Championships'), ('o', 'http://www.wikidata.org/entity/Q65687752'), ('oName', "1958 South Africa Badminton Championships – men's doubles")]
# [('s', 'http://www.wikidata.org/entity/Q15741948'), ('sName', '1956 South African Badminton Championships'), ('o', 'http://www.wikidata.org/entity/Q65687873'), ('oName', "1956 South Africa Badminton Championships – men's singles")]
# [('s', 'http://www.wikidata.org/entity/Q15741953'), ('sName', '1958 South African Badminton Championships'), ('o', 'http://www.wikidata.org/entity/Q65687877'), ('oName', "1958 South Africa Badminton Championships – men's singles")]
# [('s', 'http://www.wikidata.org/entity/Q15741948'), ('sName', '1956 South African Badminton Championships'), ('o', 'http://www.wikidata.org/entity/Q65688003'), ('oName', "1956 South Africa Badminton Championships – women's doubles")]
# [('s', 'http://www.wikidata.org/entity/Q15741953'), ('sName', '1958 South African Badminton Championships'), ('o', 'http://www.wikidata.org/entity/Q65688007'), ('oName', "1958 South Africa Badminton Championships – women's doubles")]
# [('s', 'http://www.wikidata.org/entity/Q15767688'), ('sName', '1965 South African Badminton Championships'), ('o', 'http://www.wikidata.org/entity/Q65688020'), ('oName', "1965 South Africa Badminton Championships – women's doubles")]
# [('s', 'http://www.wikidata.org/entity/Q15741948'), ('sName', '1956 South African Badminton Championships'), ('o', 'http://www.wikidata.org/entity/Q65688136'), ('oName', "1956 South Africa Badminton Championships – women's singles")]
# [('s', 'http://www.wikidata.org/entity/Q15741953'), ('sName', '1958 South African Badminton Championships'), ('o', 'http://www.wikidata.org/entity/Q65688140'), ('oName', "1958 South Africa Badminton Championships – women's singles")]
# [('s', 'http://www.wikidata.org/entity/Q15767688'), ('sName', '1965 South African Badminton Championships'), ('o', 'http://www.wikidata.org/entity/Q65688153'), ('oName', "1965 South Africa Badminton Championships – women's singles")]
# [('s', 'http://www.wikidata.org/entity/Q15741948'), ('sName', '1956 South African Badminton Championships'), ('o', 'http://www.wikidata.org/entity/Q65688271'), ('oName', '1956 South Africa Badminton Championships – mixed doubles')]
# [('s', 'http://www.wikidata.org/entity/Q15741953'), ('sName', '1958 South African Badminton Championships'), ('o', 'http://www.wikidata.org/entity/Q65688275'), ('oName', '1958 South Africa Badminton Championships – mixed doubles')]
# [('s', 'http://www.wikidata.org/entity/Q15720678'), ('sName', '2012 Greenlandic Badminton Championships'), ('o', 'http://www.wikidata.org/entity/Q79113935'), ('oName', "2012 Greenland Badminton Championships – women's doubles")]
# [('s', 'http://www.wikidata.org/entity/Q15720678'), ('sName', '2012 Greenlandic Badminton Championships'), ('o', 'http://www.wikidata.org/entity/Q79114025'), ('oName', "2012 Greenland Badminton Championships – women's singles")]
# [('s', 'http://www.wikidata.org/entity/Q15720678'), ('sName', '2012 Greenlandic Badminton Championships'), ('o', 'http://www.wikidata.org/entity/Q79114127'), ('oName', '2012 Greenland Badminton Championships – mixed doubles')]
# [('s', 'http://www.wikidata.org/entity/Q15732777'), ('sName', '2014 Iran International Badminton Championships'), ('o', 'http://www.wikidata.org/entity/Q79390986'), ('oName', "2014 Iran International Badminton Championships – men's doubles")]
# [('s', 'http://www.wikidata.org/entity/Q15732777'), ('sName', '2014 Iran International Badminton Championships'), ('o', 'http://www.wikidata.org/entity/Q79391040'), ('oName', "2014 Iran International Badminton Championships – men's singles")]
# [('s', 'http://www.wikidata.org/entity/Q15732777'), ('sName', '2014 Iran International Badminton Championships'), ('o', 'http://www.wikidata.org/entity/Q79391095'), ('oName', "2014 Iran International Badminton Championships – women's doubles")]
# 100

# %%
# write your queries

# Consider the tennis players born after 1975, return who won more Grand Slams and cut the result to the top-10 (the result set must be a list of triples player IRI, label and #victories).

# from task3 [('obj', 'http://www.wikidata.org/entity/Q41520'), ('objName', 'Wimbledon Championships')]
# <---P31 instance of -- Q30085309 '2018 Wimbledon Championships'
# --P527 ('has part')--> Q30098268 "2018 Wimbledon Championships – Women's Singles" --> P1346 ('winner') -->

# from query 5 Q5812'), ('winnerName', 'Novak Djokovic')]
# 1) getting winners dob 

#[('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('o', 'http://www.wikidata.org/entity/P569'), ('oName', 'date of birth')]
queryString = """

SELECT DISTINCT ?s ?sName ?o ?oName
WHERE {
   # ?s wdt:P1963 ?o .
   # get the label 
   # ?s sc:name ?sName.
   # ?o sc:name ?oName.
}
LIMIT 100

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('s', 'http://www.wikidata.org/entity/Q386724'), ('sName', 'work'), ('o', 'http://www.wikidata.org/entity/P747'), ('oName', 'has edition or translation')]
# [('s', 'http://www.wikidata.org/entity/Q11513337'), ('sName', 'athletics competitor'), ('o', 'http://www.wikidata.org/entity/P1146'), ('oName', 'World Athletics athlete ID')]
# [('s', 'http://www.wikidata.org/entity/Q11513337'), ('sName', 'athletics competitor'), ('o', 'http://www.wikidata.org/entity/P3765'), ('oName', 'All-Athletics.com ID')]
# [('s', 'http://www.wikidata.org/entity/Q11513337'), ('sName', 'athletics competitor'), ('o', 'http://www.wikidata.org/entity/P3882'), ('oName', 'Tilastopaja female athlete ID')]
# [('s', 'http://www.wikidata.org/entity/Q11513337'), ('sName', 'athletics competitor'), ('o', 'http://www.wikidata.org/entity/P3884'), ('oName', 'Tilastopaja male athlete ID')]
# [('s', 'http://www.wikidata.org/entity/Q11513337'), ('sName', 'athletics competitor'), ('o', 'http://www.wikidata.org/entity/P3923'), ('oName', 'Diamond League athlete ID')]
# [('s', 'http://www.wikidata.org/entity/Q11513337'), ('sName', 'athletics competitor'), ('o', 'http://www.wikidata.org/entity/P5073'), ('oName', 'JAAF athlete ID')]
# [('s', 'http://www.wikidata.org/entity/Q11513337'), ('sName', 'athletics competitor'), ('o', 'http://www.wikidata.org/entity/P5075'), ('oName', 'Polish Athletics Federation ID')]
# [('s', 'http://www.wikidata.org/entity/Q11513337'), ('sName', 'athletics competitor'), ('o', 'http://www.wikidata.org/entity/P5077'), ('oName', 'Russian Athletics ID')]
# [('s', 'http://www.wikidata.org/entity/Q105729294'), ('sName', 'Wikimedia list of musical works by instrumentation (P870)'), ('o', 'http://www.wikidata.org/entity/P360'), ('oName', 'is a list of')]
# [('s', 'http://www.wikidata.org/entity/Q59248059'), ('sName', 'singles discography'), ('o', 'http://www.wikidata.org/entity/P360'), ('oName', 'is a list of')]
# [('s', 'http://www.wikidata.org/entity/Q12139612'), ('sName', 'list'), ('o', 'http://www.wikidata.org/entity/P360'), ('oName', 'is a list of')]
# [('s', 'http://www.wikidata.org/entity/Q100775361'), ('sName', 'Wikimedia list of musical works by composer'), ('o', 'http://www.wikidata.org/entity/P360'), ('oName', 'is a list of')]
# [('s', 'http://www.wikidata.org/entity/Q100746750'), ('sName', 'Wikimedia video game music discography'), ('o', 'http://www.wikidata.org/entity/P360'), ('oName', 'is a list of')]
# [('s', 'http://www.wikidata.org/entity/Q100775856'), ('sName', 'Wikimedia list of dramatico-musical works by composer'), ('o', 'http://www.wikidata.org/entity/P360'), ('oName', 'is a list of')]
# [('s', 'http://www.wikidata.org/entity/Q101032436'), ('sName', 'Wikimedia list of musical group members'), ('o', 'http://www.wikidata.org/entity/P360'), ('oName', 'is a list of')]
# [('s', 'http://www.wikidata.org/entity/Q98540827'), ('sName', 'Wikimedia discography of dramatico-musical work'), ('o', 'http://www.wikidata.org/entity/P360'), ('oName', 'is a list of')]
# [('s', 'http://www.wikidata.org/entity/Q100707366'), ('sName', 'Wikimedia talent show discography'), ('o', 'http://www.wikidata.org/entity/P360'), ('oName', 'is a list of')]
# [('s', 'http://www.wikidata.org/entity/Q13406463'), ('sName', 'Wikimedia list article'), ('o', 'http://www.wikidata.org/entity/P360'), ('oName', 'is a list of')]
# [('s', 'http://www.wikidata.org/entity/Q2159907'), ('sName', 'criminal'), ('o', 'http://www.wikidata.org/entity/P1399'), ('oName', 'convicted of')]
# [('s', 'http://www.wikidata.org/entity/Q15795874'), ('sName', 'character in the Doctor Who Universe'), ('o', 'http://www.wikidata.org/entity/P31'), ('oName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q18219090'), ('sName', 'woodcut print'), ('o', 'http://www.wikidata.org/entity/P31'), ('oName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q12143'), ('sName', 'time zone'), ('o', 'http://www.wikidata.org/entity/P31'), ('oName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q202444'), ('sName', 'given name'), ('o', 'http://www.wikidata.org/entity/P31'), ('oName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q61663696'), ('sName', 'bicycle-sharing station'), ('o', 'http://www.wikidata.org/entity/P31'), ('oName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q757292'), ('sName', 'border checkpoint'), ('o', 'http://www.wikidata.org/entity/P31'), ('oName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q160016'), ('sName', 'member states of the United Nations'), ('o', 'http://www.wikidata.org/entity/P31'), ('oName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q17272482'), ('sName', 'time zone named for a UTC offset'), ('o', 'http://www.wikidata.org/entity/P31'), ('oName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q17444909'), ('sName', 'astronomical object type'), ('o', 'http://www.wikidata.org/entity/P31'), ('oName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q21191270'), ('sName', 'television series episode'), ('o', 'http://www.wikidata.org/entity/P31'), ('oName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q235557'), ('sName', 'file format'), ('o', 'http://www.wikidata.org/entity/P31'), ('oName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q35127'), ('sName', 'website'), ('o', 'http://www.wikidata.org/entity/P31'), ('oName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q4167836'), ('sName', 'Wikimedia category'), ('o', 'http://www.wikidata.org/entity/P31'), ('oName', 'instance of')]
# [('s', 'http://www.wikidata.org/entity/Q170790'), ('sName', 'mathematician'), ('o', 'http://www.wikidata.org/entity/P1455'), ('oName', 'list of works')]
# [('s', 'http://www.wikidata.org/entity/Q1930187'), ('sName', 'journalist'), ('o', 'http://www.wikidata.org/entity/P1455'), ('oName', 'list of works')]
# [('s', 'http://www.wikidata.org/entity/Q3839081'), ('sName', 'disaster'), ('o', 'http://www.wikidata.org/entity/P1478'), ('oName', 'has immediate cause')]
# [('s', 'http://www.wikidata.org/entity/Q3839081'), ('sName', 'disaster'), ('o', 'http://www.wikidata.org/entity/P1479'), ('oName', 'has contributing factor')]
# [('s', 'http://www.wikidata.org/entity/Q645883'), ('sName', 'military operation'), ('o', 'http://www.wikidata.org/entity/P1542'), ('oName', 'has effect')]
# [('s', 'http://www.wikidata.org/entity/Q732577'), ('sName', 'publication'), ('o', 'http://www.wikidata.org/entity/P393'), ('oName', 'edition number')]
# [('s', 'http://www.wikidata.org/entity/Q27020041'), ('sName', 'sports season'), ('o', 'http://www.wikidata.org/entity/P393'), ('oName', 'edition number')]
# [('s', 'http://www.wikidata.org/entity/Q27968043'), ('sName', 'festival edition'), ('o', 'http://www.wikidata.org/entity/P393'), ('oName', 'edition number')]
# [('s', 'http://www.wikidata.org/entity/Q4504495'), ('sName', 'award ceremony'), ('o', 'http://www.wikidata.org/entity/P393'), ('oName', 'edition number')]
# [('s', 'http://www.wikidata.org/entity/Q13442814'), ('sName', 'scholarly article'), ('o', 'http://www.wikidata.org/entity/P478'), ('oName', 'volume')]
# [('s', 'http://www.wikidata.org/entity/Q5707594'), ('sName', 'news article'), ('o', 'http://www.wikidata.org/entity/P1433'), ('oName', 'published in')]
# [('s', 'http://www.wikidata.org/entity/Q13442814'), ('sName', 'scholarly article'), ('o', 'http://www.wikidata.org/entity/P1433'), ('oName', 'published in')]
# [('s', 'http://www.wikidata.org/entity/Q15092344'), ('sName', 'urban area in Norway'), ('o', 'http://www.wikidata.org/entity/P2046'), ('oName', 'area')]
# [('s', 'http://www.wikidata.org/entity/Q291177'), ('sName', 'rose garden'), ('o', 'http://www.wikidata.org/entity/P2046'), ('oName', 'area')]
# [('s', 'http://www.wikidata.org/entity/Q1187580'), ('sName', 'non-metropolitan district'), ('o', 'http://www.wikidata.org/entity/P2046'), ('oName', 'area')]
# [('s', 'http://www.wikidata.org/entity/Q55998242'), ('sName', 'Administrative Region of Quebec'), ('o', 'http://www.wikidata.org/entity/P2046'), ('oName', 'area')]
# [('s', 'http://www.wikidata.org/entity/Q815741'), ('sName', 'geometric shape'), ('o', 'http://www.wikidata.org/entity/P2046'), ('oName', 'area')]
# [('s', 'http://www.wikidata.org/entity/Q23442'), ('sName', 'island'), ('o', 'http://www.wikidata.org/entity/P2046'), ('oName', 'area')]
# [('s', 'http://www.wikidata.org/entity/Q46169'), ('sName', 'national park'), ('o', 'http://www.wikidata.org/entity/P2046'), ('oName', 'area')]
# [('s', 'http://www.wikidata.org/entity/Q386724'), ('sName', 'work'), ('o', 'http://www.wikidata.org/entity/P406'), ('oName', 'soundtrack release')]
# [('s', 'http://www.wikidata.org/entity/Q4022'), ('sName', 'river'), ('o', 'http://www.wikidata.org/entity/P4614'), ('oName', 'drainage basin')]
# [('s', 'http://www.wikidata.org/entity/Q105543609'), ('sName', 'musical work/composition'), ('o', 'http://www.wikidata.org/entity/P6670'), ('oName', 'musical quotation or excerpt')]
# [('s', 'http://www.wikidata.org/entity/Q4610556'), ('sName', 'model'), ('o', 'http://www.wikidata.org/entity/P2266'), ('oName', 'FMD model ID')]
# [('s', 'http://www.wikidata.org/entity/Q4830453'), ('sName', 'business'), ('o', 'http://www.wikidata.org/entity/P414'), ('oName', 'stock exchange')]
# [('s', 'http://www.wikidata.org/entity/Q70990126'), ('sName', 'creative work season'), ('o', 'http://www.wikidata.org/entity/P1113'), ('oName', 'number of episodes')]
# [('s', 'http://www.wikidata.org/entity/Q63952888'), ('sName', 'anime television series'), ('o', 'http://www.wikidata.org/entity/P1113'), ('oName', 'number of episodes')]
# [('s', 'http://www.wikidata.org/entity/Q2031291'), ('sName', 'release'), ('o', 'http://www.wikidata.org/entity/P2635'), ('oName', 'number of parts of this work')]
# [('s', 'http://www.wikidata.org/entity/Q105543609'), ('sName', 'musical work/composition'), ('o', 'http://www.wikidata.org/entity/P2635'), ('oName', 'number of parts of this work')]
# [('s', 'http://www.wikidata.org/entity/Q134556'), ('sName', 'single'), ('o', 'http://www.wikidata.org/entity/P2635'), ('oName', 'number of parts of this work')]
# [('s', 'http://www.wikidata.org/entity/Q386724'), ('sName', 'work'), ('o', 'http://www.wikidata.org/entity/P2635'), ('oName', 'number of parts of this work')]
# [('s', 'http://www.wikidata.org/entity/Q482994'), ('sName', 'album'), ('o', 'http://www.wikidata.org/entity/P2635'), ('oName', 'number of parts of this work')]
# [('s', 'http://www.wikidata.org/entity/Q5137576'), ('sName', 'ice hockey coach'), ('o', 'http://www.wikidata.org/entity/P4319'), ('oName', 'Elite Prospects staff ID')]
# [('s', 'http://www.wikidata.org/entity/Q22582645'), ('sName', 'Wikidata property for properties'), ('o', 'http://www.wikidata.org/entity/P2271'), ('oName', 'Wikidata property example for properties')]
# [('s', 'http://www.wikidata.org/entity/Q1071027'), ('sName', 'personal name'), ('o', 'http://www.wikidata.org/entity/P1559'), ('oName', 'name in native language')]
# [('s', 'http://www.wikidata.org/entity/Q815741'), ('sName', 'geometric shape'), ('o', 'http://www.wikidata.org/entity/P2547'), ('oName', 'perimeter')]
# [('s', 'http://www.wikidata.org/entity/Q23442'), ('sName', 'island'), ('o', 'http://www.wikidata.org/entity/P2547'), ('oName', 'perimeter')]
# [('s', 'http://www.wikidata.org/entity/Q655311'), ('sName', 'onsen'), ('o', 'http://www.wikidata.org/entity/P2555'), ('oName', 'fee')]
# [('s', 'http://www.wikidata.org/entity/Q95074'), ('sName', 'fictional character'), ('o', 'http://www.wikidata.org/entity/P509'), ('oName', 'cause of death')]
# [('s', 'http://www.wikidata.org/entity/Q4'), ('sName', 'death'), ('o', 'http://www.wikidata.org/entity/P509'), ('oName', 'cause of death')]
# [('s', 'http://www.wikidata.org/entity/Q18219090'), ('sName', 'woodcut print'), ('o', 'http://www.wikidata.org/entity/P1259'), ('oName', 'coordinates of the point of view')]
# [('s', 'http://www.wikidata.org/entity/Q51255340'), ('sName', 'type specimen'), ('o', 'http://www.wikidata.org/entity/P195'), ('oName', 'collection')]
# [('s', 'http://www.wikidata.org/entity/Q18219090'), ('sName', 'woodcut print'), ('o', 'http://www.wikidata.org/entity/P195'), ('oName', 'collection')]
# [('s', 'http://www.wikidata.org/entity/Q543654'), ('sName', 'city hall'), ('o', 'http://www.wikidata.org/entity/P2002'), ('oName', 'Twitter username')]
# [('s', 'http://www.wikidata.org/entity/Q1968122'), ('sName', 'national Red Cross and Red Crescent society'), ('o', 'http://www.wikidata.org/entity/P2002'), ('oName', 'Twitter username')]
# [('s', 'http://www.wikidata.org/entity/Q4830453'), ('sName', 'business'), ('o', 'http://www.wikidata.org/entity/P2002'), ('oName', 'Twitter username')]
# [('s', 'http://www.wikidata.org/entity/Q11344'), ('sName', 'chemical element'), ('o', 'http://www.wikidata.org/entity/P2101'), ('oName', 'melting point')]
# [('s', 'http://www.wikidata.org/entity/Q732577'), ('sName', 'publication'), ('o', 'http://www.wikidata.org/entity/P291'), ('oName', 'place of publication')]
# [('s', 'http://www.wikidata.org/entity/Q2031291'), ('sName', 'release'), ('o', 'http://www.wikidata.org/entity/P291'), ('oName', 'place of publication')]
# [('s', 'http://www.wikidata.org/entity/Q133492'), ('sName', 'letter'), ('o', 'http://www.wikidata.org/entity/P291'), ('oName', 'place of publication')]
# [('s', 'http://www.wikidata.org/entity/Q134556'), ('sName', 'single'), ('o', 'http://www.wikidata.org/entity/P291'), ('oName', 'place of publication')]
# [('s', 'http://www.wikidata.org/entity/Q482994'), ('sName', 'album'), ('o', 'http://www.wikidata.org/entity/P291'), ('oName', 'place of publication')]
# [('s', 'http://www.wikidata.org/entity/Q575759'), ('sName', 'war memorial'), ('o', 'http://www.wikidata.org/entity/P3038'), ('oName', 'IWM memorial ID')]
# [('s', 'http://www.wikidata.org/entity/Q3839081'), ('sName', 'disaster'), ('o', 'http://www.wikidata.org/entity/P3082'), ('oName', 'destroyed')]
# [('s', 'http://www.wikidata.org/entity/Q193977'), ('sName', 'music video'), ('o', 'http://www.wikidata.org/entity/P345'), ('oName', 'IMDb ID')]
# [('s', 'http://www.wikidata.org/entity/Q11424'), ('sName', 'film'), ('o', 'http://www.wikidata.org/entity/P345'), ('oName', 'IMDb ID')]
# [('s', 'http://www.wikidata.org/entity/Q33999'), ('sName', 'actor'), ('o', 'http://www.wikidata.org/entity/P345'), ('oName', 'IMDb ID')]
# [('s', 'http://www.wikidata.org/entity/Q575759'), ('sName', 'war memorial'), ('o', 'http://www.wikidata.org/entity/P5956'), ('oName', 'War Memorials Online ID')]
# [('s', 'http://www.wikidata.org/entity/Q12397176'), ('sName', 'parish of Galicia'), ('o', 'http://www.wikidata.org/entity/P935'), ('oName', 'Commons gallery')]
# [('s', 'http://www.wikidata.org/entity/Q20541692'), ('sName', 'settlement in Galicia, Spain'), ('o', 'http://www.wikidata.org/entity/P935'), ('oName', 'Commons gallery')]
# [('s', 'http://www.wikidata.org/entity/Q11424'), ('sName', 'film'), ('o', 'http://www.wikidata.org/entity/P1040'), ('oName', 'film editor')]
# [('s', 'http://www.wikidata.org/entity/Q2658935'), ('sName', 'beauty contest'), ('o', 'http://www.wikidata.org/entity/P3085'), ('oName', 'qualifies for event')]
# [('s', 'http://www.wikidata.org/entity/Q11424'), ('sName', 'film'), ('o', 'http://www.wikidata.org/entity/P344'), ('oName', 'director of photography')]
# [('s', 'http://www.wikidata.org/entity/Q43229'), ('sName', 'organization'), ('o', 'http://www.wikidata.org/entity/P3500'), ('oName', 'Ringgold ID')]
# [('s', 'http://www.wikidata.org/entity/Q47461344'), ('sName', 'written work'), ('o', 'http://www.wikidata.org/entity/P214'), ('oName', 'VIAF ID')]
# [('s', 'http://www.wikidata.org/entity/Q235557'), ('sName', 'file format'), ('o', 'http://www.wikidata.org/entity/P2699'), ('oName', 'URL')]
# [('s', 'http://www.wikidata.org/entity/Q16521'), ('sName', 'taxon'), ('o', 'http://www.wikidata.org/entity/P3251'), ('oName', 'minimum viable temperature')]
# [('s', 'http://www.wikidata.org/entity/Q16521'), ('sName', 'taxon'), ('o', 'http://www.wikidata.org/entity/P3252'), ('oName', 'maximum viable temperature')]
# 100

# %%
# write your queries

# Consider the tennis players born after 1975, return who won more Grand Slams and cut the result to the top-10 (the result set must be a list of triples player IRI, label and #victories).

# from task3 [('obj', 'http://www.wikidata.org/entity/Q41520'), ('objName', 'Wimbledon Championships')]
# <---P31 instance of -- Q30085309 '2018 Wimbledon Championships'
# --P527 ('has part')--> Q30098268 "2018 Wimbledon Championships – Women's Singles" --> P1346 ('winner') -->

# from query 5 Q5812'), ('winnerName', 'Novak Djokovic')]
# 1) getting winners dob 

#[('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('o', 'http://www.wikidata.org/entity/P569'), ('oName', 'date of birth')]
queryString = """

SELECT DISTINCT ?s ?sName ?p ?pName
WHERE {
   # ?s ?p wd:P569.
   # get the label 
   # ?s sc:name ?sName.
   # ?p sc:name ?pName.
}
LIMIT 100

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('s', 'http://www.wikidata.org/entity/P2668'), ('sName', 'stability of property value'), ('p', 'http://www.wikidata.org/prop/direct/P2271'), ('pName', 'Wikidata property example for properties')]
# [('s', 'http://www.wikidata.org/entity/P3713'), ('sName', 'category for value not in Wikidata'), ('p', 'http://www.wikidata.org/prop/direct/P2271'), ('pName', 'Wikidata property example for properties')]
# [('s', 'http://www.wikidata.org/entity/P2302'), ('sName', 'property constraint'), ('p', 'http://www.wikidata.org/prop/direct/P2271'), ('pName', 'Wikidata property example for properties')]
# [('s', 'http://www.wikidata.org/entity/Q2389905'), ('sName', 'date of birth'), ('p', 'http://www.wikidata.org/prop/direct/P1687'), ('pName', 'Wikidata property')]
# [('s', 'http://www.wikidata.org/entity/Q105731028'), ('sName', 'by year of birth'), ('p', 'http://www.wikidata.org/prop/direct/P1687'), ('pName', 'Wikidata property')]
# [('s', 'http://www.wikidata.org/entity/Q1294626'), ('sName', 'music artist'), ('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type')]
# [('s', 'http://www.wikidata.org/entity/Q76740096'), ('sName', 'Thematic block "birth" for Template:Global Infobox person'), ('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type')]
# [('s', 'http://www.wikidata.org/entity/Q5'), ('sName', 'human'), ('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type')]
# [('s', 'http://www.wikidata.org/entity/Q26950764'), ('sName', 'organizational founder'), ('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type')]
# [('s', 'http://www.wikidata.org/entity/Q726'), ('sName', 'horse'), ('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type')]
# [('s', 'http://www.wikidata.org/entity/Q95074'), ('sName', 'fictional character'), ('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type')]
# [('s', 'http://www.wikidata.org/entity/Q1607826'), ('sName', 'editor'), ('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type')]
# [('s', 'http://www.wikidata.org/entity/Q11505877'), ('sName', 'local assemblyperson of Japan'), ('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type')]
# [('s', 'http://www.wikidata.org/entity/Q36834'), ('sName', 'composer'), ('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type')]
# [('s', 'http://www.wikidata.org/entity/Q34358'), ('sName', 'The Doctor'), ('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type')]
# [('s', 'http://www.wikidata.org/entity/Q82955'), ('sName', 'politician'), ('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type')]
# [('s', 'http://www.wikidata.org/entity/Q19332013'), ('sName', 'Category:Pages with P569 (date of birth) identical with Wikidata'), ('p', 'http://www.wikidata.org/prop/direct/P1659'), ('pName', 'see also')]
# [('s', 'http://www.wikidata.org/entity/Q39599131'), ('sName', 'Category:Creator templates with Wikidata link: item missing birthdate'), ('p', 'http://www.wikidata.org/prop/direct/P1659'), ('pName', 'see also')]
# [('s', 'http://www.wikidata.org/entity/P1317'), ('sName', 'floruit'), ('p', 'http://www.wikidata.org/prop/direct/P1659'), ('pName', 'see also')]
# [('s', 'http://www.wikidata.org/entity/Q21096033'), ('sName', 'Category:Pages using Wikidata property P569'), ('p', 'http://www.wikidata.org/prop/direct/P1659'), ('pName', 'see also')]
# [('s', 'http://www.wikidata.org/entity/P19'), ('sName', 'place of birth'), ('p', 'http://www.wikidata.org/prop/direct/P1659'), ('pName', 'see also')]
# [('s', 'http://www.wikidata.org/entity/Q19332014'), ('sName', 'Category:Pages with P569 (date of birth) different from Wikidata'), ('p', 'http://www.wikidata.org/prop/direct/P1659'), ('pName', 'see also')]
# [('s', 'http://www.wikidata.org/entity/Q19332015'), ('sName', 'Category:Date of birth not in Wikidata'), ('p', 'http://www.wikidata.org/prop/direct/P1659'), ('pName', 'see also')]
# [('s', 'http://www.wikidata.org/entity/Q28858522'), ('sName', 'Category:Articles with Template:Bio and date of birth not in Wikidata, but available on Wikipedia'), ('p', 'http://www.wikidata.org/prop/direct/P1659'), ('pName', 'see also')]
# [('s', 'http://www.wikidata.org/entity/P3150'), ('sName', 'birthday'), ('p', 'http://www.wikidata.org/prop/direct/P1659'), ('pName', 'see also')]
# [('s', 'http://www.wikidata.org/entity/P1636'), ('sName', 'date of baptism in early childhood'), ('p', 'http://www.wikidata.org/prop/direct/P1659'), ('pName', 'see also')]
# [('s', 'http://www.wikidata.org/entity/Q19389637'), ('sName', 'biographical article'), ('p', 'http://www.wikidata.org/prop/direct/P8952'), ('pName', 'inappropriate property for this type')]
# [('s', 'http://www.wikidata.org/entity/P570'), ('sName', 'date of death'), ('p', 'http://www.wikidata.org/prop/direct/P8882'), ('pName', 'complementary property')]
# [('s', 'http://www.wikidata.org/entity/Q26912459'), ('sName', 'WikiReading: A Novel Large-scale Language Understanding Task over Wikipedia'), ('p', 'http://www.wikidata.org/prop/direct/P3176'), ('pName', 'uses property')]
# [('s', 'http://www.wikidata.org/entity/Q27036482'), ('sName', 'Reifying RDF: What Works Well With Wikidata?'), ('p', 'http://www.wikidata.org/prop/direct/P3176'), ('pName', 'uses property')]
# [('s', 'http://www.wikidata.org/entity/Q27037432'), ('sName', 'Extraction of Lethal Events from Wikipedia and a Semantic Repository'), ('p', 'http://www.wikidata.org/prop/direct/P3176'), ('pName', 'uses property')]
# [('s', 'http://www.wikidata.org/entity/Q27038126'), ('sName', 'Extraction of Career Profiles from Wikipedia'), ('p', 'http://www.wikidata.org/prop/direct/P3176'), ('pName', 'uses property')]
# [('s', 'http://www.wikidata.org/entity/Q27036465'), ('sName', 'Introducing Wikidata to the Linked Data Web'), ('p', 'http://www.wikidata.org/prop/direct/P3176'), ('pName', 'uses property')]
# [('s', 'http://www.wikidata.org/entity/Q27055377'), ('sName', '‘Is’ to ‘Was’: Coordination and Commemoration on Posthumous Wikipedia Biographies'), ('p', 'http://www.wikidata.org/prop/direct/P3176'), ('pName', 'uses property')]
# [('s', 'http://www.wikidata.org/entity/Q26955946'), ('sName', 'Monitoring the Gender Gap with Wikidata Human Gender Indicators'), ('p', 'http://www.wikidata.org/prop/direct/P3176'), ('pName', 'uses property')]
# 35

# %%
# write your queries

# Consider the tennis players born after 1975, return who won more Grand Slams and cut the result to the top-10 (the result set must be a list of triples player IRI, label and #victories).

# from task3 [('obj', 'http://www.wikidata.org/entity/Q41520'), ('objName', 'Wimbledon Championships')]
# <---P31 instance of -- Q30085309 '2018 Wimbledon Championships'
# --P527 ('has part')--> Q30098268 "2018 Wimbledon Championships – Women's Singles" --> P1346 ('winner') -->

# from query 5 Q5812'), ('winnerName', 'Novak Djokovic')]
# 1) getting winners dob 

#[('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('o', 'http://www.wikidata.org/entity/P569'), ('oName', 'date of birth')]
queryString = """

SELECT DISTINCT ?p ?pName ?o ?oName
WHERE {
   wd:P569 ?p ?o .
   # get the label 
   # ?p sc:name ?pName.
   # ?o sc:name ?oName.
}
LIMIT 50

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P3709'), ('pName', 'category for value different from Wikidata'), ('o', 'http://www.wikidata.org/entity/Q19332014'), ('oName', 'Category:Pages with P569 (date of birth) different from Wikidata')]
# [('p', 'http://www.wikidata.org/prop/direct/P1659'), ('pName', 'see also'), ('o', 'http://www.wikidata.org/entity/P1317'), ('oName', 'floruit')]
# [('p', 'http://www.wikidata.org/prop/direct/P1659'), ('pName', 'see also'), ('o', 'http://www.wikidata.org/entity/P3150'), ('oName', 'birthday')]
# [('p', 'http://www.wikidata.org/prop/direct/P1855'), ('pName', 'Wikidata property example'), ('o', 'http://www.wikidata.org/entity/Q160432'), ('oName', 'Jude Law')]
# [('p', 'http://www.wikidata.org/prop/direct/P1855'), ('pName', 'Wikidata property example'), ('o', 'http://www.wikidata.org/entity/Q935'), ('oName', 'Isaac Newton')]
# [('p', 'http://www.wikidata.org/prop/direct/P1629'), ('pName', 'Wikidata item of this property'), ('o', 'http://www.wikidata.org/entity/Q2389905'), ('oName', 'date of birth')]
# [('p', 'http://www.wikidata.org/prop/direct/P1647'), ('pName', 'subproperty of'), ('o', 'http://www.wikidata.org/entity/P571'), ('oName', 'inception')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('o', 'http://www.wikidata.org/entity/Q18636219'), ('oName', "Wikidata property with datatype 'time'")]
# [('p', 'http://www.wikidata.org/prop/direct/P8379'), ('pName', 'qualifier for this property'), ('o', 'http://www.wikidata.org/entity/P1480'), ('oName', 'sourcing circumstances')]
# [('p', 'http://www.wikidata.org/prop/direct/P1855'), ('pName', 'Wikidata property example'), ('o', 'http://www.wikidata.org/entity/Q165968'), ('oName', 'Manco Cápac')]
# [('p', 'http://www.wikidata.org/prop/direct/P8882'), ('pName', 'complementary property'), ('o', 'http://www.wikidata.org/entity/P570'), ('oName', 'date of death')]
# [('p', 'http://www.wikidata.org/prop/direct/P2668'), ('pName', 'stability of property value'), ('o', 'http://www.wikidata.org/entity/Q23611288'), ('oName', 'never changes')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('o', 'http://www.wikidata.org/entity/Q18608756'), ('oName', 'Wikidata property for birth or death')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('o', 'http://www.wikidata.org/entity/Q18608871'), ('oName', 'Wikidata property for items about people')]
# [('p', 'http://www.wikidata.org/prop/direct/P2302'), ('pName', 'property constraint'), ('o', 'http://www.wikidata.org/entity/Q21502838'), ('oName', 'conflicts-with constraint')]
# [('p', 'http://www.wikidata.org/prop/direct/P2302'), ('pName', 'property constraint'), ('o', 'http://www.wikidata.org/entity/Q21503247'), ('oName', 'item-requires-statement constraint')]
# [('p', 'http://www.wikidata.org/prop/direct/P2302'), ('pName', 'property constraint'), ('o', 'http://www.wikidata.org/entity/Q21503250'), ('oName', 'type constraint')]
# [('p', 'http://www.wikidata.org/prop/direct/P2302'), ('pName', 'property constraint'), ('o', 'http://www.wikidata.org/entity/Q21510851'), ('oName', 'allowed qualifiers constraint')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('o', 'http://www.wikidata.org/entity/Q26935994'), ('oName', 'Wikidata property encoding a vCard value')]
# [('p', 'http://www.wikidata.org/prop/direct/P8274'), ('pName', 'living people protection class'), ('o', 'http://www.wikidata.org/entity/Q44601380'), ('oName', 'property that may violate privacy')]
# [('p', 'http://www.wikidata.org/prop/direct/P2302'), ('pName', 'property constraint'), ('o', 'http://www.wikidata.org/entity/Q52004125'), ('oName', 'allowed entity types constraint')]
# [('p', 'http://www.wikidata.org/prop/direct/P2302'), ('pName', 'property constraint'), ('o', 'http://www.wikidata.org/entity/Q52060874'), ('oName', 'single-best-value constraint')]
# [('p', 'http://www.wikidata.org/prop/direct/P2302'), ('pName', 'property constraint'), ('o', 'http://www.wikidata.org/entity/Q53869507'), ('oName', 'property scope constraint')]
# [('p', 'http://www.wikidata.org/prop/direct/P2302'), ('pName', 'property constraint'), ('o', 'http://www.wikidata.org/entity/Q54554025'), ('oName', 'citation needed constraint')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('o', 'http://www.wikidata.org/entity/Q99567026'), ('oName', 'Wikidata property with a single value, but different precisions and references can lead to multiple values')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('o', 'http://www.wikidata.org/entity/Q18668171'), ('oName', 'orderable Wikidata property')]
# [('p', 'http://www.wikidata.org/prop/direct/P2302'), ('pName', 'property constraint'), ('o', 'http://www.wikidata.org/entity/Q21510860'), ('oName', 'range constraint')]
# [('p', 'http://www.wikidata.org/prop/direct/P1659'), ('pName', 'see also'), ('o', 'http://www.wikidata.org/entity/P1636'), ('oName', 'date of baptism in early childhood')]
# [('p', 'http://www.wikidata.org/prop/direct/P1855'), ('pName', 'Wikidata property example'), ('o', 'http://www.wikidata.org/entity/Q17386627'), ('oName', 'Lucy F. Simms')]
# [('p', 'http://www.wikidata.org/prop/direct/P3734'), ('pName', 'category for value same as Wikidata'), ('o', 'http://www.wikidata.org/entity/Q19332013'), ('oName', 'Category:Pages with P569 (date of birth) identical with Wikidata')]
# [('p', 'http://www.wikidata.org/prop/direct/P3713'), ('pName', 'category for value not in Wikidata'), ('o', 'http://www.wikidata.org/entity/Q19332015'), ('oName', 'Category:Date of birth not in Wikidata')]
# [('p', 'http://www.wikidata.org/prop/direct/P2875'), ('pName', 'property usage tracking category'), ('o', 'http://www.wikidata.org/entity/Q21096033'), ('oName', 'Category:Pages using Wikidata property P569')]
# [('p', 'http://www.wikidata.org/prop/direct/P2354'), ('pName', 'has list'), ('o', 'http://www.wikidata.org/entity/Q21540125'), ('oName', 'Birthday today')]
# [('p', 'http://www.wikidata.org/prop/direct/P3713'), ('pName', 'category for value not in Wikidata'), ('o', 'http://www.wikidata.org/entity/Q28858522'), ('oName', 'Category:Articles with Template:Bio and date of birth not in Wikidata, but available on Wikipedia')]
# [('p', 'http://www.wikidata.org/prop/direct/P3713'), ('pName', 'category for value not in Wikidata'), ('o', 'http://www.wikidata.org/entity/Q39599131'), ('oName', 'Category:Creator templates with Wikidata link: item missing birthdate')]
# 35

# %%
# write your queries

# Consider the tennis players born after 1975, return who won more Grand Slams and cut the result to the top-10 (the result set must be a list of triples player IRI, label and #victories).

# from task3 [('obj', 'http://www.wikidata.org/entity/Q41520'), ('objName', 'Wimbledon Championships')]
# <---P31 instance of -- Q30085309 '2018 Wimbledon Championships'
# --P527 ('has part')--> Q30098268 "2018 Wimbledon Championships – Women's Singles" --> P1346 ('winner') -->

# from query 5 Q5812'), ('winnerName', 'Novak Djokovic')]
# 1) getting winners dob 

#[('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('o', 'http://www.wikidata.org/entity/P569'), ('oName', 'date of birth')]
queryString = """

SELECT NOW()
WHERE {
   wd:P569 ?p ?o .
}
LIMIT 50

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('callret-0', '2022-12-09T14:56:01.185593')]
# [('callret-0', '2022-12-09T14:56:01.185593')]
# [('callret-0', '2022-12-09T14:56:01.185593')]
# [('callret-0', '2022-12-09T14:56:01.185593')]
# [('callret-0', '2022-12-09T14:56:01.185593')]
# [('callret-0', '2022-12-09T14:56:01.185593')]
# [('callret-0', '2022-12-09T14:56:01.185593')]
# [('callret-0', '2022-12-09T14:56:01.185593')]
# [('callret-0', '2022-12-09T14:56:01.185593')]
# [('callret-0', '2022-12-09T14:56:01.185593')]
# [('callret-0', '2022-12-09T14:56:01.185593')]
# [('callret-0', '2022-12-09T14:56:01.185593')]
# [('callret-0', '2022-12-09T14:56:01.185593')]
# [('callret-0', '2022-12-09T14:56:01.185593')]
# [('callret-0', '2022-12-09T14:56:01.185593')]
# [('callret-0', '2022-12-09T14:56:01.185593')]
# [('callret-0', '2022-12-09T14:56:01.185593')]
# [('callret-0', '2022-12-09T14:56:01.185593')]
# [('callret-0', '2022-12-09T14:56:01.185593')]
# [('callret-0', '2022-12-09T14:56:01.185593')]
# [('callret-0', '2022-12-09T14:56:01.185593')]
# [('callret-0', '2022-12-09T14:56:01.185593')]
# [('callret-0', '2022-12-09T14:56:01.185593')]
# [('callret-0', '2022-12-09T14:56:01.185593')]
# [('callret-0', '2022-12-09T14:56:01.185593')]
# [('callret-0', '2022-12-09T14:56:01.185593')]
# [('callret-0', '2022-12-09T14:56:01.185593')]
# [('callret-0', '2022-12-09T14:56:01.185593')]
# [('callret-0', '2022-12-09T14:56:01.185593')]
# [('callret-0', '2022-12-09T14:56:01.185593')]
# [('callret-0', '2022-12-09T14:56:01.185593')]
# [('callret-0', '2022-12-09T14:56:01.185593')]
# [('callret-0', '2022-12-09T14:56:01.185593')]
# [('callret-0', '2022-12-09T14:56:01.185593')]
# [('callret-0', '2022-12-09T14:56:01.185593')]
# [('callret-0', '2022-12-09T14:56:01.185593')]
# [('callret-0', '2022-12-09T14:56:01.185593')]
# [('callret-0', '2022-12-09T14:56:01.185593')]
# [('callret-0', '2022-12-09T14:56:01.185593')]
# [('callret-0', '2022-12-09T14:56:01.185593')]
# [('callret-0', '2022-12-09T14:56:01.185593')]
# [('callret-0', '2022-12-09T14:56:01.185593')]
# [('callret-0', '2022-12-09T14:56:01.185593')]
# [('callret-0', '2022-12-09T14:56:01.185593')]
# [('callret-0', '2022-12-09T14:56:01.185593')]
# [('callret-0', '2022-12-09T14:56:01.185593')]
# [('callret-0', '2022-12-09T14:56:01.185593')]
# [('callret-0', '2022-12-09T14:56:01.185593')]
# [('callret-0', '2022-12-09T14:56:01.185593')]
# [('callret-0', '2022-12-09T14:56:01.185593')]
# 50

# %%
# Consider the tennis players born after 1975, return who won more Grand Slams and cut the result to the top-10 (the result set must be a list of triples player IRI, label and #victories).
# Q1426 = Roger Federer
# wdt:P1344 (participant in)
# wdt:P2522 (victory)

# 1) getting winners dob 
queryString = """

SELECT DISTINCT ?p ?pName ?o ?oName
WHERE {
   wd:Q1426 ?p ?o .
   # get the label 
   # ?p sc:name ?pName.
   # ?o sc:name ?oName.
   FILTER (?p != wdt:P1344 && ?p != wdt:P2522)
}
LIMIT 50
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P103'), ('pName', 'native language'), ('o', 'http://www.wikidata.org/entity/Q188'), ('oName', 'German')]
# [('p', 'http://www.wikidata.org/prop/direct/P106'), ('pName', 'occupation'), ('o', 'http://www.wikidata.org/entity/Q10833314'), ('oName', 'tennis player')]
# [('p', 'http://www.wikidata.org/prop/direct/P108'), ('pName', 'employer'), ('o', 'http://www.wikidata.org/entity/Q740308'), ('oName', 'UNICEF')]
# [('p', 'http://www.wikidata.org/prop/direct/P1343'), ('pName', 'described by source'), ('o', 'http://www.wikidata.org/entity/Q17290934'), ('oName', 'Lentapedia')]
# [('p', 'http://www.wikidata.org/prop/direct/P1343'), ('pName', 'described by source'), ('o', 'http://www.wikidata.org/entity/Q67311526'), ('oName', 'Obalky knih.cz')]
# [('p', 'http://www.wikidata.org/prop/direct/P140'), ('pName', 'religion'), ('o', 'http://www.wikidata.org/entity/Q9592'), ('oName', 'Catholic Church')]
# [('p', 'http://www.wikidata.org/prop/direct/P1412'), ('pName', 'languages spoken, written or signed'), ('o', 'http://www.wikidata.org/entity/Q150'), ('oName', 'French')]
# [('p', 'http://www.wikidata.org/prop/direct/P1412'), ('pName', 'languages spoken, written or signed'), ('o', 'http://www.wikidata.org/entity/Q1860'), ('oName', 'English')]
# [('p', 'http://www.wikidata.org/prop/direct/P1412'), ('pName', 'languages spoken, written or signed'), ('o', 'http://www.wikidata.org/entity/Q188'), ('oName', 'German')]
# [('p', 'http://www.wikidata.org/prop/direct/P1532'), ('pName', 'country for sport'), ('o', 'http://www.wikidata.org/entity/Q39'), ('oName', 'Switzerland')]
# [('p', 'http://www.wikidata.org/prop/direct/P166'), ('pName', 'award received'), ('o', 'http://www.wikidata.org/entity/Q56509472'), ('oName', 'honorary doctor of the University of Basel')]
# [('p', 'http://www.wikidata.org/prop/direct/P166'), ('pName', 'award received'), ('o', 'http://www.wikidata.org/entity/Q1061233'), ('oName', "L'Équipe Champion of Champions")]
# [('p', 'http://www.wikidata.org/prop/direct/P166'), ('pName', 'award received'), ('o', 'http://www.wikidata.org/entity/Q338737'), ('oName', 'Swiss Sports Personality of the Year')]
# [('p', 'http://www.wikidata.org/prop/direct/P166'), ('pName', 'award received'), ('o', 'http://www.wikidata.org/entity/Q3494048'), ('oName', 'BBC Overseas Sports Personality of the Year')]
# [('p', 'http://www.wikidata.org/prop/direct/P166'), ('pName', 'award received'), ('o', 'http://www.wikidata.org/entity/Q4896696'), ('oName', 'Best International Athlete ESPY Award')]
# [('p', 'http://www.wikidata.org/prop/direct/P166'), ('pName', 'award received'), ('o', 'http://www.wikidata.org/entity/Q693708'), ('oName', 'ITF World Champions')]
# [('p', 'http://www.wikidata.org/prop/direct/P19'), ('pName', 'place of birth'), ('o', 'http://www.wikidata.org/entity/Q78'), ('oName', 'Basel')]
# [('p', 'http://www.wikidata.org/prop/direct/P21'), ('pName', 'sex or gender'), ('o', 'http://www.wikidata.org/entity/Q6581097'), ('oName', 'male')]
# [('p', 'http://www.wikidata.org/prop/direct/P22'), ('pName', 'father'), ('o', 'http://www.wikidata.org/entity/Q17291275'), ('oName', 'Robert Federer')]
# [('p', 'http://www.wikidata.org/prop/direct/P2416'), ('pName', 'sports discipline competed in'), ('o', 'http://www.wikidata.org/entity/Q18123880'), ('oName', 'tennis singles')]
# [('p', 'http://www.wikidata.org/prop/direct/P2416'), ('pName', 'sports discipline competed in'), ('o', 'http://www.wikidata.org/entity/Q18123885'), ('oName', 'tennis doubles')]
# [('p', 'http://www.wikidata.org/prop/direct/P25'), ('pName', 'mother'), ('o', 'http://www.wikidata.org/entity/Q17291278'), ('oName', 'Lynette Federer')]
# [('p', 'http://www.wikidata.org/prop/direct/P26'), ('pName', 'spouse'), ('o', 'http://www.wikidata.org/entity/Q233306'), ('oName', 'Mirka Federer')]
# [('p', 'http://www.wikidata.org/prop/direct/P27'), ('pName', 'country of citizenship'), ('o', 'http://www.wikidata.org/entity/Q39'), ('oName', 'Switzerland')]
# [('p', 'http://www.wikidata.org/prop/direct/P286'), ('pName', 'head coach'), ('o', 'http://www.wikidata.org/entity/Q15649219'), ('oName', 'Severin Lüthi')]
# [('p', 'http://www.wikidata.org/prop/direct/P286'), ('pName', 'head coach'), ('o', 'http://www.wikidata.org/entity/Q261095'), ('oName', 'Ivan Ljubičić')]
# [('p', 'http://www.wikidata.org/prop/direct/P286'), ('pName', 'head coach'), ('o', 'http://www.wikidata.org/entity/Q1348847'), ('oName', 'José Higueras')]
# [('p', 'http://www.wikidata.org/prop/direct/P286'), ('pName', 'head coach'), ('o', 'http://www.wikidata.org/entity/Q1968483'), ('oName', 'Peter Carter')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('o', 'http://www.wikidata.org/entity/Q5'), ('oName', 'human')]
# [('p', 'http://www.wikidata.org/prop/direct/P3342'), ('pName', 'significant person'), ('o', 'http://www.wikidata.org/entity/Q54584'), ('oName', 'Andy Roddick')]
# [('p', 'http://www.wikidata.org/prop/direct/P3373'), ('pName', 'sibling'), ('o', 'http://www.wikidata.org/entity/Q17291284'), ('oName', 'Dziana Federer')]
# [('p', 'http://www.wikidata.org/prop/direct/P39'), ('pName', 'position held'), ('o', 'http://www.wikidata.org/entity/Q19969187'), ('oName', 'UNICEF Goodwill Ambassador')]
# [('p', 'http://www.wikidata.org/prop/direct/P40'), ('pName', 'child'), ('o', 'http://www.wikidata.org/entity/Q17291294'), ('oName', 'Myla Federer')]
# [('p', 'http://www.wikidata.org/prop/direct/P40'), ('pName', 'child'), ('o', 'http://www.wikidata.org/entity/Q17291300'), ('oName', 'Charlene Federer')]
# [('p', 'http://www.wikidata.org/prop/direct/P40'), ('pName', 'child'), ('o', 'http://www.wikidata.org/entity/Q17291308'), ('oName', 'Leo Federer')]
# [('p', 'http://www.wikidata.org/prop/direct/P40'), ('pName', 'child'), ('o', 'http://www.wikidata.org/entity/Q17291316'), ('oName', 'Lennart Federer')]
# [('p', 'http://www.wikidata.org/prop/direct/P463'), ('pName', 'member of'), ('o', 'http://www.wikidata.org/entity/Q1675504'), ('oName', 'Swiss Tennis')]
# [('p', 'http://www.wikidata.org/prop/direct/P551'), ('pName', 'residence'), ('o', 'http://www.wikidata.org/entity/Q70036'), ('oName', 'Bottmingen')]
# [('p', 'http://www.wikidata.org/prop/direct/P552'), ('pName', 'handedness'), ('o', 'http://www.wikidata.org/entity/Q3039938'), ('oName', 'right-handedness')]
# [('p', 'http://www.wikidata.org/prop/direct/P641'), ('pName', 'sport'), ('o', 'http://www.wikidata.org/entity/Q847'), ('oName', 'tennis')]
# [('p', 'http://www.wikidata.org/prop/direct/P734'), ('pName', 'family name'), ('o', 'http://www.wikidata.org/entity/Q16869916'), ('oName', 'Federer')]
# [('p', 'http://www.wikidata.org/prop/direct/P735'), ('pName', 'given name'), ('o', 'http://www.wikidata.org/entity/Q4925304'), ('oName', 'Roger')]
# [('p', 'http://www.wikidata.org/prop/direct/P741'), ('pName', 'playing hand'), ('o', 'http://www.wikidata.org/entity/Q14420039'), ('oName', 'one-handed backhand')]
# [('p', 'http://www.wikidata.org/prop/direct/P741'), ('pName', 'playing hand'), ('o', 'http://www.wikidata.org/entity/Q14419931'), ('oName', 'one-handed forehand')]
# [('p', 'http://www.wikidata.org/prop/direct/P910'), ('pName', "topic's main category"), ('o', 'http://www.wikidata.org/entity/Q7257144'), ('oName', 'Category:Roger Federer')]
# [('p', 'http://www.wikidata.org/prop/direct/P6758'), ('pName', 'supported sports team'), ('o', 'http://www.wikidata.org/entity/Q189671'), ('oName', 'FC Basel')]
# 46

# %%
# Consider the tennis players born after 1975, return who won more Grand Slams and cut the result to the top-10 (the result set must be a list of triples player IRI, label and #victories).
# Q1426 = Roger Federer
# wdt:P1344 (participant in)
# wdt:P2522 (victory)

# 1) getting winners dob 
queryString = """

SELECT DISTINCT ?p ?pName
WHERE {
   wd:Q1426 ?p ?o .
   # get the label 
   # ?p sc:name ?pName.
   # ?o sc:name ?oName.
   # FILTER (?p != wdt:P1344 && ?p != wdt:P2522)
}
LIMIT 50
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P2522'), ('pName', 'victory')]
# [('p', 'http://www.wikidata.org/prop/direct/P3342'), ('pName', 'significant person')]
# [('p', 'http://www.wikidata.org/prop/direct/P166'), ('pName', 'award received')]
# [('p', 'http://www.wikidata.org/prop/direct/P1344'), ('pName', 'participant in')]
# [('p', 'http://www.wikidata.org/prop/direct/P6758'), ('pName', 'supported sports team')]
# [('p', 'http://www.wikidata.org/prop/direct/P106'), ('pName', 'occupation')]
# [('p', 'http://www.wikidata.org/prop/direct/P741'), ('pName', 'playing hand')]
# [('p', 'http://www.wikidata.org/prop/direct/P1412'), ('pName', 'languages spoken, written or signed')]
# [('p', 'http://www.wikidata.org/prop/direct/P1343'), ('pName', 'described by source')]
# [('p', 'http://www.wikidata.org/prop/direct/P103'), ('pName', 'native language')]
# [('p', 'http://www.wikidata.org/prop/direct/P39'), ('pName', 'position held')]
# [('p', 'http://www.wikidata.org/prop/direct/P552'), ('pName', 'handedness')]
# [('p', 'http://www.wikidata.org/prop/direct/P1532'), ('pName', 'country for sport')]
# [('p', 'http://www.wikidata.org/prop/direct/P27'), ('pName', 'country of citizenship')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('p', 'http://www.wikidata.org/prop/direct/P21'), ('pName', 'sex or gender')]
# [('p', 'http://www.wikidata.org/prop/direct/P108'), ('pName', 'employer')]
# [('p', 'http://www.wikidata.org/prop/direct/P19'), ('pName', 'place of birth')]
# [('p', 'http://www.wikidata.org/prop/direct/P641'), ('pName', 'sport')]
# [('p', 'http://www.wikidata.org/prop/direct/P140'), ('pName', 'religion')]
# [('p', 'http://www.wikidata.org/prop/direct/P2416'), ('pName', 'sports discipline competed in')]
# [('p', 'http://www.wikidata.org/prop/direct/P735'), ('pName', 'given name')]
# [('p', 'http://www.wikidata.org/prop/direct/P551'), ('pName', 'residence')]
# [('p', 'http://www.wikidata.org/prop/direct/P286'), ('pName', 'head coach')]
# [('p', 'http://www.wikidata.org/prop/direct/P734'), ('pName', 'family name')]
# [('p', 'http://www.wikidata.org/prop/direct/P22'), ('pName', 'father')]
# [('p', 'http://www.wikidata.org/prop/direct/P25'), ('pName', 'mother')]
# [('p', 'http://www.wikidata.org/prop/direct/P3373'), ('pName', 'sibling')]
# [('p', 'http://www.wikidata.org/prop/direct/P40'), ('pName', 'child')]
# [('p', 'http://www.wikidata.org/prop/direct/P26'), ('pName', 'spouse')]
# [('p', 'http://www.wikidata.org/prop/direct/P910'), ('pName', "topic's main category")]
# [('p', 'http://www.wikidata.org/prop/direct/P463'), ('pName', 'member of')]
# 32

# %%
# Consider the tennis players born after 1975, return who won more Grand Slams and cut the result to the top-10 (the result set must be a list of triples player IRI, label and #victories).
# Q1426 = Roger Federer
# wdt:P1344 (participant in)
# wdt:P2522 (victory)

# 1) getting winners dob 
queryString = """

SELECT DISTINCT ?s ?sName ?p ?pName
WHERE {
   # ?s ?p wd:Q1426.
   # get the label 
   # ?p sc:name ?pName.
   # ?s sc:name ?sName.
}
LIMIT 200
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('s', 'http://www.wikidata.org/entity/Q22956224'), ('sName', "2017 Australian Open – Men's Singles"), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner')]
# [('s', 'http://www.wikidata.org/entity/Q3983549'), ('sName', '2007 Tennis Masters Cup – singles'), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner')]
# [('s', 'http://www.wikidata.org/entity/Q2537671'), ('sName', '2011 Qatar Open – singles'), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner')]
# [('s', 'http://www.wikidata.org/entity/Q13076407'), ('sName', "2012 Mutua Madrid Open – Men's Singles"), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner')]
# [('s', 'http://www.wikidata.org/entity/Q30311438'), ('sName', '2017 Gerry Weber Open – singles'), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner')]
# [('s', 'http://www.wikidata.org/entity/Q3633911'), ('sName', '2005 Western & Southern Financial Group Masters – singles'), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner')]
# [('s', 'http://www.wikidata.org/entity/Q54584'), ('sName', 'Andy Roddick'), ('p', 'http://www.wikidata.org/prop/direct/P3342'), ('pName', 'significant person')]
# [('s', 'http://www.wikidata.org/entity/Q782589'), ('sName', "2010 Australian Open – Men's Singles"), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner')]
# [('s', 'http://www.wikidata.org/entity/Q58363'), ('sName', "2006 NASDAQ-100 Open – Men's Singles"), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner')]
# [('s', 'http://www.wikidata.org/entity/Q3720084'), ('sName', 'Nick Kyrgios'), ('p', 'http://www.wikidata.org/prop/direct/P737'), ('pName', 'influenced by')]
# [('s', 'http://www.wikidata.org/entity/Q782420'), ('sName', "2006 Australian Open – Men's Singles"), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner')]
# [('s', 'http://www.wikidata.org/entity/Q1808301'), ('sName', 'Laureus World Sports Award for Sportsman of the Year'), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner')]
# [('s', 'http://www.wikidata.org/entity/Q3816928'), ('sName', "2002 Kremlin Cup – Men's Doubles"), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner')]
# [('s', 'http://www.wikidata.org/entity/Q4601774'), ('sName', '2003 Roger Federer tennis season'), ('p', 'http://www.wikidata.org/prop/direct/P1269'), ('pName', 'facet of')]
# [('s', 'http://www.wikidata.org/entity/Q23766780'), ('sName', '2016 Monte-Carlo Rolex Masters – singles'), ('p', 'http://www.wikidata.org/prop/direct/P710'), ('pName', 'participant')]
# [('s', 'http://www.wikidata.org/entity/Q28869949'), ('sName', "2017 BNP Paribas Open – Men's Singles"), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner')]
# [('s', 'http://www.wikidata.org/entity/Q33092'), ('sName', '2008 Gerry Weber Open – singles'), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner')]
# [('s', 'http://www.wikidata.org/entity/Q3494048'), ('sName', 'BBC Overseas Sports Personality of the Year'), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner')]
# [('s', 'http://www.wikidata.org/entity/Q753300'), ('sName', "2012 Wimbledon Championships – Gentlemen's Singles"), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner')]
# [('s', 'http://www.wikidata.org/entity/Q757054'), ('sName', "tennis at the 2008 Summer Olympics – men's doubles"), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner')]
# [('s', 'http://www.wikidata.org/entity/Q1074654'), ('sName', "2006 Wimbledon Championships – Men's Singles"), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner')]
# [('s', 'http://www.wikidata.org/entity/Q384929'), ('sName', "2005 Wimbledon Championships – Men's Singles"), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner')]
# [('s', 'http://www.wikidata.org/entity/Q15666697'), ('sName', '2014 Roger Federer tennis season'), ('p', 'http://www.wikidata.org/prop/direct/P1269'), ('pName', 'facet of')]
# [('s', 'http://www.wikidata.org/entity/Q33458'), ('sName', '2005 Gerry Weber Open – singles'), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner')]
# [('s', 'http://www.wikidata.org/entity/Q1644845'), ('sName', '2005 Qatar Open – singles'), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner')]
# [('s', 'http://www.wikidata.org/entity/Q3634285'), ('sName', '2003 CA-TennisTrophy – singles'), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner')]
# [('s', 'http://www.wikidata.org/entity/Q16983050'), ('sName', '2014 Gerry Weber Open – singles'), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner')]
# [('s', 'http://www.wikidata.org/entity/Q18336310'), ('sName', '2014 Swiss Indoors – singles'), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner')]
# [('s', 'http://www.wikidata.org/entity/Q3869381'), ('sName', "2003 NASDAQ-100 Open – Men's Doubles"), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner')]
# [('s', 'http://www.wikidata.org/entity/Q4612261'), ('sName', "2008 Wimbledon Championships – Men's Singles final"), ('p', 'http://www.wikidata.org/prop/direct/P710'), ('pName', 'participant')]
# [('s', 'http://www.wikidata.org/entity/Q4629801'), ('sName', '2013 Roger Federer tennis season'), ('p', 'http://www.wikidata.org/prop/direct/P1269'), ('pName', 'facet of')]
# [('s', 'http://www.wikidata.org/entity/Q3703751'), ('sName', '2008 Davidoff Swiss Indoors – singles'), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner')]
# [('s', 'http://www.wikidata.org/entity/P536'), ('sName', 'ATP player ID'), ('p', 'http://www.wikidata.org/prop/direct/P1855'), ('pName', 'Wikidata property example')]
# [('s', 'http://www.wikidata.org/entity/Q58465'), ('sName', "2005 NASDAQ-100 Open – Men's Singles"), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner')]
# [('s', 'http://www.wikidata.org/entity/P555'), ('sName', 'doubles record'), ('p', 'http://www.wikidata.org/prop/direct/P1855'), ('pName', 'Wikidata property example')]
# [('s', 'http://www.wikidata.org/entity/Q13423423'), ('sName', '2013 Gerry Weber Open – singles'), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner')]
# [('s', 'http://www.wikidata.org/entity/Q2613138'), ('sName', "2012 Dubai Tennis Championships – Men's Singles"), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner')]
# [('s', 'http://www.wikidata.org/entity/Q1648328'), ('sName', '2006 Rogers Masters – singles'), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner')]
# [('s', 'http://www.wikidata.org/entity/P6308'), ('sName', 'Scoresway tennis person ID'), ('p', 'http://www.wikidata.org/prop/direct/P1855'), ('pName', 'Wikidata property example')]
# [('s', 'http://www.wikidata.org/entity/Q336862'), ('sName', 'Guido Pella'), ('p', 'http://www.wikidata.org/prop/direct/P737'), ('pName', 'influenced by')]
# [('s', 'http://www.wikidata.org/entity/Q20088951'), ('sName', '2015 Gerry Weber Open – singles'), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner')]
# [('s', 'http://www.wikidata.org/entity/Q4622262'), ('sName', '2011 Roger Federer tennis season'), ('p', 'http://www.wikidata.org/prop/direct/P1269'), ('pName', 'facet of')]
# [('s', 'http://www.wikidata.org/entity/Q20745019'), ('sName', 'Luca Margaroli'), ('p', 'http://www.wikidata.org/prop/direct/P737'), ('pName', 'influenced by')]
# [('s', 'http://www.wikidata.org/entity/Q46993124'), ('sName', "2018 Australian Open – Men's Singles"), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner')]
# [('s', 'http://www.wikidata.org/entity/Q47501368'), ('sName', '2018 Roger Federer tennis season'), ('p', 'http://www.wikidata.org/prop/direct/P1269'), ('pName', 'facet of')]
# [('s', 'http://www.wikidata.org/entity/Q47501368'), ('sName', '2018 Roger Federer tennis season'), ('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of')]
# [('s', 'http://www.wikidata.org/entity/Q775304'), ('sName', "2002 Adidas International – Men's Singles"), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner')]
# [('s', 'http://www.wikidata.org/entity/Q54813043'), ('sName', 'Lorenzo Musetti'), ('p', 'http://www.wikidata.org/prop/direct/P737'), ('pName', 'influenced by')]
# [('s', 'http://www.wikidata.org/entity/Q4896696'), ('sName', 'Best International Athlete ESPY Award'), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner')]
# [('s', 'http://www.wikidata.org/entity/Q4896731'), ('sName', 'Best Male Tennis Player ESPY Award'), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner')]
# [('s', 'http://www.wikidata.org/entity/Q649333'), ('sName', 'Márton Fucsovics'), ('p', 'http://www.wikidata.org/prop/direct/P737'), ('pName', 'influenced by')]
# [('s', 'http://www.wikidata.org/entity/Q2297012'), ('sName', '2010 Western & Southern Financial Group Masters – singles'), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner')]
# [('s', 'http://www.wikidata.org/entity/Q3703744'), ('sName', '2006 Davidoff Swiss Indoors – singles'), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner')]
# [('s', 'http://www.wikidata.org/entity/Q18710512'), ('sName', "2015 Brisbane International – Men's Singles"), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner')]
# [('s', 'http://www.wikidata.org/entity/Q3632075'), ('sName', '2003 BMW Open – singles'), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner')]
# [('s', 'http://www.wikidata.org/entity/Q1085070'), ('sName', '2010 If Stockholm Open – singles'), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner')]
# [('s', 'http://www.wikidata.org/entity/Q1644814'), ('sName', '2006 Qatar Open – singles'), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner')]
# [('s', 'http://www.wikidata.org/entity/Q3782837'), ('sName', '2005 Hamburg Masters – singles'), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner')]
# [('s', 'http://www.wikidata.org/entity/Q15796942'), ('sName', "2014 Dubai Tennis Championships – Men's Singles"), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner')]
# [('s', 'http://www.wikidata.org/entity/Q19832529'), ('sName', '2015 Istanbul Open – singles'), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner')]
# [('s', 'http://www.wikidata.org/entity/Q2478962'), ('sName', '2011 ATP World Tour Finals – singles'), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner')]
# [('s', 'http://www.wikidata.org/entity/Q2735325'), ('sName', "2009 Mutua Madrileña Madrid Open – Men's Singles"), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner')]
# [('s', 'http://www.wikidata.org/entity/Q2902229'), ('sName', 'Big Four'), ('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part')]
# [('s', 'http://www.wikidata.org/entity/Q3978960'), ('sName', '2004 Allianz Suisse Open Gstaad – singles'), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner')]
# [('s', 'http://www.wikidata.org/entity/Q3703727'), ('sName', '2000 Davidoff Swiss Indoors – singles'), ('p', 'http://www.wikidata.org/prop/direct/P710'), ('pName', 'participant')]
# [('s', 'http://www.wikidata.org/entity/Q3978828'), ('sName', '2010 Swiss Indoors – singles'), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner')]
# [('s', 'http://www.wikidata.org/entity/Q3983544'), ('sName', '2006 Tennis Masters Cup – singles'), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner')]
# [('s', 'http://www.wikidata.org/entity/Q3985427'), ('sName', '2005 Thailand Open – singles'), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner')]
# [('s', 'http://www.wikidata.org/entity/Q7358176'), ('sName', 'Roger Federer junior years'), ('p', 'http://www.wikidata.org/prop/direct/P1269'), ('pName', 'facet of')]
# [('s', 'http://www.wikidata.org/entity/Q15457453'), ('sName', '2002 Roger Federer tennis season'), ('p', 'http://www.wikidata.org/prop/direct/P1269'), ('pName', 'facet of')]
# [('s', 'http://www.wikidata.org/entity/Q599040'), ('sName', "2008 Estoril Open – Men's Singles"), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner')]
# [('s', 'http://www.wikidata.org/entity/Q1048953'), ('sName', "2004 US Open – Men's Singles"), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner')]
# [('s', 'http://www.wikidata.org/entity/Q731509'), ('sName', "2005 US Open – Men's Singles"), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner')]
# [('s', 'http://www.wikidata.org/entity/Q741573'), ('sName', "2009 French Open – Men's Singles"), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner')]
# [('s', 'http://www.wikidata.org/entity/Q912506'), ('sName', "2006 US Open – Men's Singles"), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner')]
# [('s', 'http://www.wikidata.org/entity/Q248965'), ('sName', "2004 Wimbledon Championships – Men's Singles"), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner')]
# [('s', 'http://www.wikidata.org/entity/Q378627'), ('sName', "2003 Wimbledon Championships – Men's Singles"), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner')]
# [('s', 'http://www.wikidata.org/entity/Q3634280'), ('sName', '2002 CA-TennisTrophy – singles'), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner')]
# [('s', 'http://www.wikidata.org/entity/Q171829'), ('sName', "2012 BNP Paribas Open – Men's Singles"), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner')]
# [('s', 'http://www.wikidata.org/entity/Q779654'), ('sName', "2004 Australian Open - men's singles"), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner')]
# [('s', 'http://www.wikidata.org/entity/Q2025562'), ('sName', '2000 Open 13 – singles'), ('p', 'http://www.wikidata.org/prop/direct/P710'), ('pName', 'participant')]
# [('s', 'http://www.wikidata.org/entity/Q3983537'), ('sName', '2003 Tennis Masters Cup – singles'), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner')]
# [('s', 'http://www.wikidata.org/entity/Q1006209'), ('sName', 'list of career achievements by Roger Federer'), ('p', 'http://www.wikidata.org/prop/direct/P1269'), ('pName', 'facet of')]
# [('s', 'http://www.wikidata.org/entity/Q33089'), ('sName', '2006 Gerry Weber Open – singles'), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner')]
# [('s', 'http://www.wikidata.org/entity/Q3761294'), ('sName', '2004 Gerry Weber Open – singles'), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner')]
# [('s', 'http://www.wikidata.org/entity/Q4603249'), ('sName', '2004 Roger Federer tennis season'), ('p', 'http://www.wikidata.org/prop/direct/P1269'), ('pName', 'facet of')]
# [('s', 'http://www.wikidata.org/entity/Q4604471'), ('sName', '2005 Kooyong Classic – Draw'), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner')]
# [('s', 'http://www.wikidata.org/entity/Q4614681'), ('sName', '2009 Roger Federer tennis season'), ('p', 'http://www.wikidata.org/prop/direct/P1269'), ('pName', 'facet of')]
# [('s', 'http://www.wikidata.org/entity/Q523802'), ('sName', 'Marco Chiudinelli'), ('p', 'http://www.wikidata.org/prop/direct/P737'), ('pName', 'influenced by')]
# [('s', 'http://www.wikidata.org/entity/Q25344123'), ('sName', "2017 Wimbledon Championships – Men's Singles"), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner')]
# [('s', 'http://www.wikidata.org/entity/Q42308390'), ('sName', '2017 Swiss Indoors – singles'), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner')]
# [('s', 'http://www.wikidata.org/entity/Q17291275'), ('sName', 'Robert Federer'), ('p', 'http://www.wikidata.org/prop/direct/P40'), ('pName', 'child')]
# [('s', 'http://www.wikidata.org/entity/Q17291278'), ('sName', 'Lynette Federer'), ('p', 'http://www.wikidata.org/prop/direct/P40'), ('pName', 'child')]
# [('s', 'http://www.wikidata.org/entity/Q17291284'), ('sName', 'Dziana Federer'), ('p', 'http://www.wikidata.org/prop/direct/P3373'), ('pName', 'sibling')]
# [('s', 'http://www.wikidata.org/entity/Q17291294'), ('sName', 'Myla Federer'), ('p', 'http://www.wikidata.org/prop/direct/P22'), ('pName', 'father')]
# [('s', 'http://www.wikidata.org/entity/Q17291300'), ('sName', 'Charlene Federer'), ('p', 'http://www.wikidata.org/prop/direct/P22'), ('pName', 'father')]
# [('s', 'http://www.wikidata.org/entity/Q17291308'), ('sName', 'Leo Federer'), ('p', 'http://www.wikidata.org/prop/direct/P22'), ('pName', 'father')]
# [('s', 'http://www.wikidata.org/entity/Q17291316'), ('sName', 'Lennart Federer'), ('p', 'http://www.wikidata.org/prop/direct/P22'), ('pName', 'father')]
# [('s', 'http://www.wikidata.org/entity/Q233306'), ('sName', 'Mirka Federer'), ('p', 'http://www.wikidata.org/prop/direct/P26'), ('pName', 'spouse')]
# [('s', 'http://www.wikidata.org/entity/Q62083876'), ('sName', "2019 Miami Open – Men's Singles"), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner')]
# [('s', 'http://www.wikidata.org/entity/Q56526313'), ('sName', 'Giulio Zeppieri'), ('p', 'http://www.wikidata.org/prop/direct/P737'), ('pName', 'influenced by')]
# [('s', 'http://www.wikidata.org/entity/Q57536122'), ('sName', '2018 Swiss Indoors – singles'), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner')]
# [('s', 'http://www.wikidata.org/entity/Q20752045'), ('sName', 'Félix Auger-Aliassime'), ('p', 'http://www.wikidata.org/prop/direct/P737'), ('pName', 'influenced by')]
# [('s', 'http://www.wikidata.org/entity/Q15149640'), ('sName', '2009 Western & Southern Financial Group Masters – singles'), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner')]
# [('s', 'http://www.wikidata.org/entity/Q4626640'), ('sName', '2012 Roger Federer tennis season'), ('p', 'http://www.wikidata.org/prop/direct/P1269'), ('pName', 'facet of')]
# [('s', 'http://www.wikidata.org/entity/Q83529'), ('sName', 'Roger Federer career statistics'), ('p', 'http://www.wikidata.org/prop/direct/P1269'), ('pName', 'facet of')]
# [('s', 'http://www.wikidata.org/entity/Q2478340'), ('sName', '2011 BNP Paribas Masters – singles'), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner')]
# [('s', 'http://www.wikidata.org/entity/Q1068579'), ('sName', "2012 Western & Southern Open – Men's Singles"), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner')]
# [('s', 'http://www.wikidata.org/entity/Q3654836'), ('sName', '2004 Canada Masters – singles'), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner')]
# [('s', 'http://www.wikidata.org/entity/Q18194803'), ('sName', '2014 Shanghai Rolex Masters – singles'), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner')]
# [('s', 'http://www.wikidata.org/entity/Q48137891'), ('sName', '2018 ABN AMRO World Tennis Tournament – singles'), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner')]
# [('s', 'http://www.wikidata.org/entity/Q751798'), ('sName', "2009 Wimbledon Championships – Men's Singles"), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner')]
# [('s', 'http://www.wikidata.org/entity/Q1081552'), ('sName', '2010 ATP World Tour Finals – singles'), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner')]
# [('s', 'http://www.wikidata.org/entity/Q4032864'), ('sName', '2009 AAMI Classic – Draw'), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner')]
# [('s', 'http://www.wikidata.org/entity/Q18748113'), ('sName', '2015 Roger Federer tennis season'), ('p', 'http://www.wikidata.org/prop/direct/P1269'), ('pName', 'facet of')]
# [('s', 'http://www.wikidata.org/entity/Q1106656'), ('sName', '2011 Swiss Indoors – singles'), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner')]
# [('s', 'http://www.wikidata.org/entity/Q108353402'), ('sName', 'Sammy Wejinya'), ('p', 'http://www.wikidata.org/prop/direct/P737'), ('pName', 'influenced by')]
# [('s', 'http://www.wikidata.org/entity/Q782451'), ('sName', "2007 Australian Open – Men's Singles"), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner')]
# [('s', 'http://www.wikidata.org/entity/Q912483'), ('sName', "2007 Wimbledon Championships – Men's Singles"), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner')]
# [('s', 'http://www.wikidata.org/entity/Q4604808'), ('sName', '2005 Roger Federer tennis season'), ('p', 'http://www.wikidata.org/prop/direct/P1269'), ('pName', 'facet of')]
# [('s', 'http://www.wikidata.org/entity/Q28483608'), ('sName', "Federer beats Nishikori in Australian Open's fourth round"), ('p', 'http://www.wikidata.org/prop/direct/P921'), ('pName', 'main subject')]
# [('s', 'http://www.wikidata.org/entity/Q20821487'), ('sName', "2015 Western & Southern Open – Men's Singles"), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner')]
# [('s', 'http://www.wikidata.org/entity/Q61856750'), ('sName', "2019 Dubai Tennis Championships – Men's Singles"), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner')]
# [('s', 'http://www.wikidata.org/entity/Q54864380'), ('sName', '2018 MercedesCup – singles'), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner')]
# [('s', 'http://www.wikidata.org/entity/Q64666029'), ('sName', '2019 Noventi Open – singles'), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner')]
# [('s', 'http://www.wikidata.org/entity/Q1644820'), ('sName', "2004 Pacific Life Open – Men's Singles"), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner')]
# [('s', 'http://www.wikidata.org/entity/Q3882909'), ('sName', '2003 Open 13 – singles'), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner')]
# [('s', 'http://www.wikidata.org/entity/Q28962805'), ('sName', "2017 Miami Open – Men's Singles"), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner')]
# [('s', 'http://www.wikidata.org/entity/Q3857696'), ('sName', '2001 Milan Indoor – singles'), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner')]
# [('s', 'http://www.wikidata.org/entity/Q304072'), ('sName', "2008 US Open – Men's Singles"), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner')]
# [('s', 'http://www.wikidata.org/entity/Q4618283'), ('sName', '2010 Roger Federer tennis season'), ('p', 'http://www.wikidata.org/prop/direct/P1269'), ('pName', 'facet of')]
# [('s', 'http://www.wikidata.org/entity/Q17489108'), ('sName', "2014 Western & Southern Open – Men's Singles"), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner')]
# [('s', 'http://www.wikidata.org/entity/Q1650814'), ('sName', '2007 Western & Southern Financial Group Masters – singles'), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner')]
# [('s', 'http://www.wikidata.org/entity/Q3600561'), ('sName', '2012 ABN AMRO World Tennis Tournament – singles'), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner')]
# [('s', 'http://www.wikidata.org/entity/Q3703747'), ('sName', '2007 Davidoff Swiss Indoors – singles'), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner')]
# [('s', 'http://www.wikidata.org/entity/Q33087'), ('sName', '2003 Gerry Weber Open – singles'), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner')]
# [('s', 'http://www.wikidata.org/entity/Q3782828'), ('sName', '2002 Hamburg Masters – singles'), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner')]
# [('s', 'http://www.wikidata.org/entity/Q3782840'), ('sName', '2007 Hamburg Masters – singles'), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner')]
# [('s', 'http://www.wikidata.org/entity/Q7358175'), ('sName', "Roger Federer's early career"), ('p', 'http://www.wikidata.org/prop/direct/P1269'), ('pName', 'facet of')]
# [('s', 'http://www.wikidata.org/entity/Q3715712'), ('sName', "2005 Dubai Tennis Championships – Men's Singles"), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner')]
# [('s', 'http://www.wikidata.org/entity/Q3715700'), ('sName', '2003 Dubai Tennis Championships – singles'), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner')]
# [('s', 'http://www.wikidata.org/entity/Q3983540'), ('sName', '2004 Tennis Masters Cup – singles'), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner')]
# [('s', 'http://www.wikidata.org/entity/Q10589664'), ('sName', "2006 AIG Japan Open Tennis Championships – Men's Singles"), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner')]
# [('s', 'http://www.wikidata.org/entity/Q1644830'), ('sName', "2005 Pacific Life Open – Men's Singles"), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner')]
# [('s', 'http://www.wikidata.org/entity/Q836815'), ('sName', "2007 US Open – Men's Singles"), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner')]
# [('s', 'http://www.wikidata.org/entity/Q1749433'), ('sName', '2006 Mutua Madrilena Masters Madrid – singles'), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner')]
# [('s', 'http://www.wikidata.org/entity/Q3600547'), ('sName', '2005 ABN AMRO World Tennis Tournament – Singles'), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner')]
# [('s', 'http://www.wikidata.org/entity/Q3978948'), ('sName', '2001 UBS Open – doubles'), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner')]
# [('s', 'http://www.wikidata.org/entity/Q128122'), ('sName', 'Switzerland at the 2004 Summer Olympics'), ('p', 'http://www.wikidata.org/prop/direct/P3022'), ('pName', 'flag bearer')]
# [('s', 'http://www.wikidata.org/entity/Q15262968'), ('sName', "2007 Dubai Tennis Championships – Men's Singles"), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner')]
# [('s', 'http://www.wikidata.org/entity/Q4606872'), ('sName', '2006 Roger Federer tennis season'), ('p', 'http://www.wikidata.org/prop/direct/P1269'), ('pName', 'facet of')]
# [('s', 'http://www.wikidata.org/entity/Q7257144'), ('sName', 'Category:Roger Federer'), ('p', 'http://www.wikidata.org/prop/direct/P301'), ('pName', "category's main topic")]
# [('s', 'http://www.wikidata.org/entity/Q259735'), ('sName', '2008 Roger Federer tennis season'), ('p', 'http://www.wikidata.org/prop/direct/P1269'), ('pName', 'facet of')]
# [('s', 'http://www.wikidata.org/entity/Q5683382'), ('sName', '230975 Rogerfederer'), ('p', 'http://www.wikidata.org/prop/direct/P138'), ('pName', 'named after')]
# [('s', 'http://www.wikidata.org/entity/Q3715706'), ('sName', "2004 Dubai Tennis Championships – Men's Singles"), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner')]
# [('s', 'http://www.wikidata.org/entity/Q41646989'), ('sName', '2017 Shanghai Rolex Masters – singles'), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner')]
# [('s', 'http://www.wikidata.org/entity/Q3782835'), ('sName', '2004 Hamburg Masters – singles'), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner')]
# [('s', 'http://www.wikidata.org/entity/Q4609195'), ('sName', '2007 Roger Federer tennis season'), ('p', 'http://www.wikidata.org/prop/direct/P1269'), ('pName', 'facet of')]
# [('s', 'http://www.wikidata.org/entity/Q2393359'), ('sName', "2006 Pacific Life Open – Men's Singles"), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner')]
# [('s', 'http://www.wikidata.org/entity/Q3600542'), ('sName', '2002 ABN AMRO World Tennis Tournament – doubles'), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner')]
# [('s', 'http://www.wikidata.org/entity/Q28600417'), ('sName', "2017 Australian Open – men's singles final"), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner')]
# [('s', 'http://www.wikidata.org/entity/Q28600417'), ('sName', "2017 Australian Open – men's singles final"), ('p', 'http://www.wikidata.org/prop/direct/P710'), ('pName', 'participant')]
# [('s', 'http://www.wikidata.org/entity/Q1202961'), ('sName', 'Federer–Nadal rivalry'), ('p', 'http://www.wikidata.org/prop/direct/P710'), ('pName', 'participant')]
# [('s', 'http://www.wikidata.org/entity/Q3985424'), ('sName', '2004 Thailand Open – singles'), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner')]
# [('s', 'http://www.wikidata.org/entity/Q5440937'), ('sName', 'Federer–Roddick rivalry'), ('p', 'http://www.wikidata.org/prop/direct/P710'), ('pName', 'participant')]
# [('s', 'http://www.wikidata.org/entity/Q19059455'), ('sName', "2015 Dubai Tennis Championships – Men's Singles"), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner')]
# [('s', 'http://www.wikidata.org/entity/Q24883546'), ('sName', "1998 Wimbledon Championships – Boys' Doubles"), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner')]
# [('s', 'http://www.wikidata.org/entity/Q28537356'), ('sName', '2017 Roger Federer tennis season'), ('p', 'http://www.wikidata.org/prop/direct/P1269'), ('pName', 'facet of')]
# [('s', 'http://www.wikidata.org/entity/Q128127'), ('sName', 'Switzerland at the 2008 Summer Olympics'), ('p', 'http://www.wikidata.org/prop/direct/P3022'), ('pName', 'flag bearer')]
# [('s', 'http://www.wikidata.org/entity/Q60769022'), ('sName', '2019 Roger Federer tennis season'), ('p', 'http://www.wikidata.org/prop/direct/P3450'), ('pName', 'sports season of league or competition')]
# [('s', 'http://www.wikidata.org/entity/Q2940294'), ('sName', 'career of Roger federer'), ('p', 'http://www.wikidata.org/prop/direct/P1269'), ('pName', 'facet of')]
# [('s', 'http://www.wikidata.org/entity/Q21970584'), ('sName', 'Sneak Attack by Roger'), ('p', 'http://www.wikidata.org/prop/direct/P138'), ('pName', 'named after')]
# [('s', 'http://www.wikidata.org/entity/Q21970584'), ('sName', 'Sneak Attack by Roger'), ('p', 'http://www.wikidata.org/prop/direct/P61'), ('pName', 'discoverer or inventor')]
# [('s', 'http://www.wikidata.org/entity/Q21236654'), ('sName', '2015 Swiss Indoors – singles'), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner')]
# [('s', 'http://www.wikidata.org/entity/Q24887825'), ('sName', "1998 Wimbledon Championships – Boys' Singles"), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner')]
# [('s', 'http://www.wikidata.org/entity/Q21862656'), ('sName', '2016 Roger Federer tennis season'), ('p', 'http://www.wikidata.org/prop/direct/P1269'), ('pName', 'facet of')]
# [('s', 'http://www.wikidata.org/entity/Q71760073'), ('sName', '2019 Swiss Indoors – singles'), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner')]
# 177

# %%
# Consider the tennis players born after 1975, return who won more Grand Slams and cut the result to the top-10 (the result set must be a list of triples player IRI, label and #victories).
# Q1426 = Roger Federer
# wdt:P1344 (participant in)
# wdt:P2522 (victory)

# 1) getting winners dob 
queryString = """

SELECT DISTINCT ?p ?pName (COUNT(*) AS ?tot)
WHERE {
   # ?s ?p wd:Q1426.
   # ?p sc:name ?pName.
}
GROUP BY ?p ?pName
LIMIT 200
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P1269'), ('pName', 'facet of'), ('tot', '24')]
# [('p', 'http://www.wikidata.org/prop/direct/P40'), ('pName', 'child'), ('tot', '2')]
# [('p', 'http://www.wikidata.org/prop/direct/P26'), ('pName', 'spouse'), ('tot', '1')]
# [('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner'), ('tot', '117')]
# [('p', 'http://www.wikidata.org/prop/direct/P301'), ('pName', "category's main topic"), ('tot', '1')]
# [('p', 'http://www.wikidata.org/prop/direct/P1855'), ('pName', 'Wikidata property example'), ('tot', '3')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('tot', '1')]
# [('p', 'http://www.wikidata.org/prop/direct/P3450'), ('pName', 'sports season of league or competition'), ('tot', '1')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('tot', '1')]
# [('p', 'http://www.wikidata.org/prop/direct/P921'), ('pName', 'main subject'), ('tot', '2')]
# [('p', 'http://www.wikidata.org/prop/direct/P138'), ('pName', 'named after'), ('tot', '2')]
# [('p', 'http://www.wikidata.org/prop/direct/P22'), ('pName', 'father'), ('tot', '4')]
# [('p', 'http://www.wikidata.org/prop/direct/P3342'), ('pName', 'significant person'), ('tot', '1')]
# [('p', 'http://www.wikidata.org/prop/direct/P3022'), ('pName', 'flag bearer'), ('tot', '2')]
# [('p', 'http://www.wikidata.org/prop/direct/P3373'), ('pName', 'sibling'), ('tot', '1')]
# [('p', 'http://www.wikidata.org/prop/direct/P737'), ('pName', 'influenced by'), ('tot', '9')]
# [('p', 'http://www.wikidata.org/prop/direct/P710'), ('pName', 'participant'), ('tot', '7')]
# [('p', 'http://www.wikidata.org/prop/direct/P61'), ('pName', 'discoverer or inventor'), ('tot', '1')]
# 18

# %%
# Consider the tennis players born after 1975, return who won more Grand Slams and cut the result to the top-10 (the result set must be a list of triples player IRI, label and #victories).
# Q1426 = Roger Federer
# wdt:P1344 (participant in)
# wdt:P2522 (victory)
#[('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('o', 'http://www.wikidata.org/entity/P569'), ('oName', 'date of birth')]

# 1) getting winners dob 
queryString = """

SELECT DISTINCT ?sName ?pName ?oName
WHERE {
   # ?s ?p ?o.
   # ?s sc:name ?sName.
   # ?p sc:name ?pName.
   # ?o sc:name ?oName.
   FILTER (?s = wd:P569)
}
LIMIT 50
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('sName', 'date of birth'), ('pName', 'has list'), ('oName', 'Birthday today')]
# [('sName', 'date of birth'), ('pName', 'instance of'), ('oName', 'orderable Wikidata property')]
# [('sName', 'date of birth'), ('pName', 'instance of'), ('oName', 'Wikidata property for items about people')]
# [('sName', 'date of birth'), ('pName', 'instance of'), ('oName', "Wikidata property with datatype 'time'")]
# [('sName', 'date of birth'), ('pName', 'instance of'), ('oName', 'Wikidata property for birth or death')]
# [('sName', 'date of birth'), ('pName', 'instance of'), ('oName', 'Wikidata property with a single value, but different precisions and references can lead to multiple values')]
# [('sName', 'date of birth'), ('pName', 'instance of'), ('oName', 'Wikidata property encoding a vCard value')]
# [('sName', 'date of birth'), ('pName', 'see also'), ('oName', 'birthday')]
# [('sName', 'date of birth'), ('pName', 'see also'), ('oName', 'date of baptism in early childhood')]
# [('sName', 'date of birth'), ('pName', 'see also'), ('oName', 'floruit')]
# [('sName', 'date of birth'), ('pName', 'Wikidata item of this property'), ('oName', 'date of birth')]
# [('sName', 'date of birth'), ('pName', 'subproperty of'), ('oName', 'inception')]
# [('sName', 'date of birth'), ('pName', 'Wikidata property example'), ('oName', 'Isaac Newton')]
# [('sName', 'date of birth'), ('pName', 'Wikidata property example'), ('oName', 'Lucy F. Simms')]
# [('sName', 'date of birth'), ('pName', 'Wikidata property example'), ('oName', 'Manco Cápac')]
# [('sName', 'date of birth'), ('pName', 'Wikidata property example'), ('oName', 'Jude Law')]
# [('sName', 'date of birth'), ('pName', 'property constraint'), ('oName', 'property scope constraint')]
# [('sName', 'date of birth'), ('pName', 'property constraint'), ('oName', 'type constraint')]
# [('sName', 'date of birth'), ('pName', 'property constraint'), ('oName', 'range constraint')]
# [('sName', 'date of birth'), ('pName', 'property constraint'), ('oName', 'allowed entity types constraint')]
# [('sName', 'date of birth'), ('pName', 'property constraint'), ('oName', 'conflicts-with constraint')]
# [('sName', 'date of birth'), ('pName', 'property constraint'), ('oName', 'allowed qualifiers constraint')]
# [('sName', 'date of birth'), ('pName', 'property constraint'), ('oName', 'citation needed constraint')]
# [('sName', 'date of birth'), ('pName', 'property constraint'), ('oName', 'single-best-value constraint')]
# [('sName', 'date of birth'), ('pName', 'property constraint'), ('oName', 'item-requires-statement constraint')]
# [('sName', 'date of birth'), ('pName', 'stability of property value'), ('oName', 'never changes')]
# [('sName', 'date of birth'), ('pName', 'property usage tracking category'), ('oName', 'Category:Pages using Wikidata property P569')]
# [('sName', 'date of birth'), ('pName', 'category for value different from Wikidata'), ('oName', 'Category:Pages with P569 (date of birth) different from Wikidata')]
# [('sName', 'date of birth'), ('pName', 'category for value not in Wikidata'), ('oName', 'Category:Creator templates with Wikidata link: item missing birthdate')]
# [('sName', 'date of birth'), ('pName', 'category for value not in Wikidata'), ('oName', 'Category:Date of birth not in Wikidata')]
# [('sName', 'date of birth'), ('pName', 'category for value not in Wikidata'), ('oName', 'Category:Articles with Template:Bio and date of birth not in Wikidata, but available on Wikipedia')]
# [('sName', 'date of birth'), ('pName', 'category for value same as Wikidata'), ('oName', 'Category:Pages with P569 (date of birth) identical with Wikidata')]
# [('sName', 'date of birth'), ('pName', 'living people protection class'), ('oName', 'property that may violate privacy')]
# [('sName', 'date of birth'), ('pName', 'complementary property'), ('oName', 'date of death')]
# [('sName', 'date of birth'), ('pName', 'qualifier for this property'), ('oName', 'sourcing circumstances')]
# 35

# %%
# Consider the tennis players born after 1975, return who won more Grand Slams and cut the result to the top-10 (the result set must be a list of triples player IRI, label and #victories).
# Q1426 = Roger Federer
# wdt:P1344 (participant in)
# wdt:P2522 (victory)
#[('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('o', 'http://www.wikidata.org/entity/P569'), ('oName', 'date of birth')]

# 1) getting winners dob 
queryString = """

SELECT DISTINCT ?sName ?pName ?oName
WHERE {
   # ?s ?p ?o.
   # ?s sc:name ?sName.
   # ?p sc:name ?pName.
   # ?o sc:name ?oName.
   FILTER (?o = wd:P569)
}
LIMIT 50
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('sName', 'Category:Pages with P569 (date of birth) different from Wikidata'), ('pName', 'see also'), ('oName', 'date of birth')]
# [('sName', 'floruit'), ('pName', 'see also'), ('oName', 'date of birth')]
# [('sName', 'birthday'), ('pName', 'see also'), ('oName', 'date of birth')]
# [('sName', 'Extraction of Career Profiles from Wikipedia'), ('pName', 'uses property'), ('oName', 'date of birth')]
# [('sName', 'fictional character'), ('pName', 'properties for this type'), ('oName', 'date of birth')]
# [('sName', 'organizational founder'), ('pName', 'properties for this type'), ('oName', 'date of birth')]
# [('sName', 'category for value not in Wikidata'), ('pName', 'Wikidata property example for properties'), ('oName', 'date of birth')]
# [('sName', 'date of birth'), ('pName', 'Wikidata property'), ('oName', 'date of birth')]
# [('sName', 'composer'), ('pName', 'properties for this type'), ('oName', 'date of birth')]
# [('sName', 'human'), ('pName', 'properties for this type'), ('oName', 'date of birth')]
# [('sName', 'politician'), ('pName', 'properties for this type'), ('oName', 'date of birth')]
# [('sName', 'horse'), ('pName', 'properties for this type'), ('oName', 'date of birth')]
# [('sName', 'editor'), ('pName', 'properties for this type'), ('oName', 'date of birth')]
# [('sName', 'biographical article'), ('pName', 'inappropriate property for this type'), ('oName', 'date of birth')]
# [('sName', 'local assemblyperson of Japan'), ('pName', 'properties for this type'), ('oName', 'date of birth')]
# [('sName', 'place of birth'), ('pName', 'see also'), ('oName', 'date of birth')]
# [('sName', 'date of death'), ('pName', 'complementary property'), ('oName', 'date of birth')]
# [('sName', 'music artist'), ('pName', 'properties for this type'), ('oName', 'date of birth')]
# [('sName', 'The Doctor'), ('pName', 'properties for this type'), ('oName', 'date of birth')]
# [('sName', 'Monitoring the Gender Gap with Wikidata Human Gender Indicators'), ('pName', 'uses property'), ('oName', 'date of birth')]
# [('sName', 'property constraint'), ('pName', 'Wikidata property example for properties'), ('oName', 'date of birth')]
# [('sName', 'Reifying RDF: What Works Well With Wikidata?'), ('pName', 'uses property'), ('oName', 'date of birth')]
# [('sName', 'Introducing Wikidata to the Linked Data Web'), ('pName', 'uses property'), ('oName', 'date of birth')]
# [('sName', 'date of baptism in early childhood'), ('pName', 'see also'), ('oName', 'date of birth')]
# [('sName', 'stability of property value'), ('pName', 'Wikidata property example for properties'), ('oName', 'date of birth')]
# [('sName', 'Category:Pages with P569 (date of birth) identical with Wikidata'), ('pName', 'see also'), ('oName', 'date of birth')]
# [('sName', 'Category:Date of birth not in Wikidata'), ('pName', 'see also'), ('oName', 'date of birth')]
# [('sName', 'Category:Pages using Wikidata property P569'), ('pName', 'see also'), ('oName', 'date of birth')]
# [('sName', 'Category:Articles with Template:Bio and date of birth not in Wikidata, but available on Wikipedia'), ('pName', 'see also'), ('oName', 'date of birth')]
# [('sName', 'Category:Creator templates with Wikidata link: item missing birthdate'), ('pName', 'see also'), ('oName', 'date of birth')]
# [('sName', 'WikiReading: A Novel Large-scale Language Understanding Task over Wikipedia'), ('pName', 'uses property'), ('oName', 'date of birth')]
# [('sName', '‘Is’ to ‘Was’: Coordination and Commemoration on Posthumous Wikipedia Biographies'), ('pName', 'uses property'), ('oName', 'date of birth')]
# [('sName', 'by year of birth'), ('pName', 'Wikidata property'), ('oName', 'date of birth')]
# [('sName', 'Thematic block "birth" for Template:Global Infobox person'), ('pName', 'properties for this type'), ('oName', 'date of birth')]
# [('sName', 'Extraction of Lethal Events from Wikipedia and a Semantic Repository'), ('pName', 'uses property'), ('oName', 'date of birth')]
# 35

# %%
# Consider the tennis players born after 1975, return who won more Grand Slams and cut the result to the top-10 (the result set must be a list of triples player IRI, label and #victories).
# Q1426 = Roger Federer
# wdt:P1344 (participant in)
# wdt:P2522 (victory)
#[('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('o', 'http://www.wikidata.org/entity/P569'), ('oName', 'date of birth')]

# 1) getting winners dob 
queryString = """

SELECT DISTINCT ?pName ?o ?oName
WHERE {
   # ?s ?p ?o.
   # ?s sc:name ?sName.
   # ?p sc:name ?pName.
   # ?o sc:name ?oName.
   FILTER (?s = wd:P569)
}
LIMIT 50
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('pName', 'has list'), ('o', 'http://www.wikidata.org/entity/Q21540125'), ('oName', 'Birthday today')]
# [('pName', 'instance of'), ('o', 'http://www.wikidata.org/entity/Q18668171'), ('oName', 'orderable Wikidata property')]
# [('pName', 'instance of'), ('o', 'http://www.wikidata.org/entity/Q18608871'), ('oName', 'Wikidata property for items about people')]
# [('pName', 'instance of'), ('o', 'http://www.wikidata.org/entity/Q18636219'), ('oName', "Wikidata property with datatype 'time'")]
# [('pName', 'instance of'), ('o', 'http://www.wikidata.org/entity/Q18608756'), ('oName', 'Wikidata property for birth or death')]
# [('pName', 'instance of'), ('o', 'http://www.wikidata.org/entity/Q99567026'), ('oName', 'Wikidata property with a single value, but different precisions and references can lead to multiple values')]
# [('pName', 'instance of'), ('o', 'http://www.wikidata.org/entity/Q26935994'), ('oName', 'Wikidata property encoding a vCard value')]
# [('pName', 'see also'), ('o', 'http://www.wikidata.org/entity/P3150'), ('oName', 'birthday')]
# [('pName', 'see also'), ('o', 'http://www.wikidata.org/entity/P1636'), ('oName', 'date of baptism in early childhood')]
# [('pName', 'see also'), ('o', 'http://www.wikidata.org/entity/P1317'), ('oName', 'floruit')]
# [('pName', 'Wikidata item of this property'), ('o', 'http://www.wikidata.org/entity/Q2389905'), ('oName', 'date of birth')]
# [('pName', 'subproperty of'), ('o', 'http://www.wikidata.org/entity/P571'), ('oName', 'inception')]
# [('pName', 'Wikidata property example'), ('o', 'http://www.wikidata.org/entity/Q935'), ('oName', 'Isaac Newton')]
# [('pName', 'Wikidata property example'), ('o', 'http://www.wikidata.org/entity/Q17386627'), ('oName', 'Lucy F. Simms')]
# [('pName', 'Wikidata property example'), ('o', 'http://www.wikidata.org/entity/Q165968'), ('oName', 'Manco Cápac')]
# [('pName', 'Wikidata property example'), ('o', 'http://www.wikidata.org/entity/Q160432'), ('oName', 'Jude Law')]
# [('pName', 'property constraint'), ('o', 'http://www.wikidata.org/entity/Q53869507'), ('oName', 'property scope constraint')]
# [('pName', 'property constraint'), ('o', 'http://www.wikidata.org/entity/Q21503250'), ('oName', 'type constraint')]
# [('pName', 'property constraint'), ('o', 'http://www.wikidata.org/entity/Q21510860'), ('oName', 'range constraint')]
# [('pName', 'property constraint'), ('o', 'http://www.wikidata.org/entity/Q52004125'), ('oName', 'allowed entity types constraint')]
# [('pName', 'property constraint'), ('o', 'http://www.wikidata.org/entity/Q21502838'), ('oName', 'conflicts-with constraint')]
# [('pName', 'property constraint'), ('o', 'http://www.wikidata.org/entity/Q21510851'), ('oName', 'allowed qualifiers constraint')]
# [('pName', 'property constraint'), ('o', 'http://www.wikidata.org/entity/Q54554025'), ('oName', 'citation needed constraint')]
# [('pName', 'property constraint'), ('o', 'http://www.wikidata.org/entity/Q52060874'), ('oName', 'single-best-value constraint')]
# [('pName', 'property constraint'), ('o', 'http://www.wikidata.org/entity/Q21503247'), ('oName', 'item-requires-statement constraint')]
# [('pName', 'stability of property value'), ('o', 'http://www.wikidata.org/entity/Q23611288'), ('oName', 'never changes')]
# [('pName', 'property usage tracking category'), ('o', 'http://www.wikidata.org/entity/Q21096033'), ('oName', 'Category:Pages using Wikidata property P569')]
# [('pName', 'category for value different from Wikidata'), ('o', 'http://www.wikidata.org/entity/Q19332014'), ('oName', 'Category:Pages with P569 (date of birth) different from Wikidata')]
# [('pName', 'category for value not in Wikidata'), ('o', 'http://www.wikidata.org/entity/Q39599131'), ('oName', 'Category:Creator templates with Wikidata link: item missing birthdate')]
# [('pName', 'category for value not in Wikidata'), ('o', 'http://www.wikidata.org/entity/Q19332015'), ('oName', 'Category:Date of birth not in Wikidata')]
# [('pName', 'category for value not in Wikidata'), ('o', 'http://www.wikidata.org/entity/Q28858522'), ('oName', 'Category:Articles with Template:Bio and date of birth not in Wikidata, but available on Wikipedia')]
# [('pName', 'category for value same as Wikidata'), ('o', 'http://www.wikidata.org/entity/Q19332013'), ('oName', 'Category:Pages with P569 (date of birth) identical with Wikidata')]
# [('pName', 'living people protection class'), ('o', 'http://www.wikidata.org/entity/Q44601380'), ('oName', 'property that may violate privacy')]
# [('pName', 'complementary property'), ('o', 'http://www.wikidata.org/entity/P570'), ('oName', 'date of death')]
# [('pName', 'qualifier for this property'), ('o', 'http://www.wikidata.org/entity/P1480'), ('oName', 'sourcing circumstances')]
# 35

# %%
# Consider the tennis players born after 1975, return who won more Grand Slams and cut the result to the top-10 (the result set must be a list of triples player IRI, label and #victories).
# Q1426 = Roger Federer
# wdt:P1344 (participant in)
# wdt:P2522 (victory)
#[('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('o', 'http://www.wikidata.org/entity/P569'), ('oName', 'date of birth')]

# 1) getting winners dob 
queryString = """

SELECT DISTINCT ?pName ?o ?oName
WHERE {
   # ?s ?p ?o.
   # ?s sc:name ?sName.
   # ?p sc:name ?pName.
   # ?o sc:name ?oName.
   FILTER (?s = wd:P3150)
}
LIMIT 50
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('pName', 'instance of'), ('o', 'http://www.wikidata.org/entity/Q18608756'), ('oName', 'Wikidata property for birth or death')]
# [('pName', 'instance of'), ('o', 'http://www.wikidata.org/entity/Q26935994'), ('oName', 'Wikidata property encoding a vCard value')]
# [('pName', 'see also'), ('o', 'http://www.wikidata.org/entity/P837'), ('oName', 'day in year for periodic occurrence')]
# [('pName', 'see also'), ('o', 'http://www.wikidata.org/entity/P569'), ('oName', 'date of birth')]
# [('pName', 'Wikidata item of this property'), ('o', 'http://www.wikidata.org/entity/Q47223'), ('oName', 'birthday')]
# [('pName', 'Wikidata property example'), ('o', 'http://www.wikidata.org/entity/Q1188210'), ('oName', 'Haruka Shimotsuki')]
# [('pName', 'Wikidata property example'), ('o', 'http://www.wikidata.org/entity/Q931'), ('oName', 'Naruto Uzumaki')]
# [('pName', 'property constraint'), ('o', 'http://www.wikidata.org/entity/Q52004125'), ('oName', 'allowed entity types constraint')]
# [('pName', 'property constraint'), ('o', 'http://www.wikidata.org/entity/Q21510865'), ('oName', 'value-type constraint')]
# [('pName', 'property constraint'), ('o', 'http://www.wikidata.org/entity/Q21502838'), ('oName', 'conflicts-with constraint')]
# [('pName', 'property constraint'), ('o', 'http://www.wikidata.org/entity/Q54554025'), ('oName', 'citation needed constraint')]
# [('pName', 'property constraint'), ('o', 'http://www.wikidata.org/entity/Q21503250'), ('oName', 'type constraint')]
# [('pName', 'property constraint'), ('o', 'http://www.wikidata.org/entity/Q19474404'), ('oName', 'single-value constraint')]
# [('pName', 'property constraint'), ('o', 'http://www.wikidata.org/entity/Q21510851'), ('oName', 'allowed qualifiers constraint')]
# [('pName', 'property constraint'), ('o', 'http://www.wikidata.org/entity/Q53869507'), ('oName', 'property scope constraint')]
# [('pName', 'property constraint'), ('o', 'http://www.wikidata.org/entity/Q21503247'), ('oName', 'item-requires-statement constraint')]
# 16

# %%
# Consider the tennis players born after 1975, return who won more Grand Slams and cut the result to the top-10 (the result set must be a list of triples player IRI, label and #victories).
# Q1426 = Roger Federer
# wdt:P1344 (participant in)
# wdt:P2522 (victory)
#[('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('o', 'http://www.wikidata.org/entity/P569'), ('oName', 'date of birth')]

# 1) getting winners dob 
queryString = """

SELECT DISTINCT ?pName ?o ?oName
WHERE {
   # ?s ?p ?o.
   # ?s sc:name ?sName.
   # ?p sc:name ?pName.
   # ?o sc:name ?oName.
   FILTER (?s = wd:Q1188210)
}
LIMIT 50
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('pName', 'field of work'), ('o', 'http://www.wikidata.org/entity/Q92186587'), ('oName', 'composing')]
# [('pName', 'occupation'), ('o', 'http://www.wikidata.org/entity/Q488205'), ('oName', 'singer-songwriter')]
# [('pName', 'occupation'), ('o', 'http://www.wikidata.org/entity/Q177220'), ('oName', 'singer')]
# [('pName', 'occupation'), ('o', 'http://www.wikidata.org/entity/Q36834'), ('oName', 'composer')]
# [('pName', 'instrument'), ('o', 'http://www.wikidata.org/entity/Q17172850'), ('oName', 'voice')]
# [('pName', 'genre'), ('o', 'http://www.wikidata.org/entity/Q131578'), ('oName', 'J-pop')]
# [('pName', 'languages spoken, written or signed'), ('o', 'http://www.wikidata.org/entity/Q5287'), ('oName', 'Japanese')]
# [('pName', 'blood type'), ('o', 'http://www.wikidata.org/entity/Q19831453'), ('oName', 'A')]
# [('pName', 'place of birth'), ('o', 'http://www.wikidata.org/entity/Q47896'), ('oName', 'Miyagi Prefecture')]
# [('pName', 'sex or gender'), ('o', 'http://www.wikidata.org/entity/Q6581072'), ('oName', 'female')]
# [('pName', 'record label'), ('o', 'http://www.wikidata.org/entity/Q11250534'), ('oName', 'TEAM Entertainment')]
# [('pName', 'country of citizenship'), ('o', 'http://www.wikidata.org/entity/Q17'), ('oName', 'Japan')]
# [('pName', 'instance of'), ('o', 'http://www.wikidata.org/entity/Q5'), ('oName', 'human')]
# [('pName', 'educated at'), ('o', 'http://www.wikidata.org/entity/Q7498329'), ('oName', "Shirayuri Women's University")]
# [('pName', 'family name'), ('o', 'http://www.wikidata.org/entity/Q105525833'), ('oName', 'Shimotsuki')]
# [('pName', 'given name'), ('o', 'http://www.wikidata.org/entity/Q938731'), ('oName', 'Haruka')]
# 16

# %%
# Consider the tennis players born after 1975, return who won more Grand Slams and cut the result to the top-10 (the result set must be a list of triples player IRI, label and #victories).
# Q1426 = Roger Federer
# wdt:P1344 (participant in)
# wdt:P2522 (victory)
#[('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('o', 'http://www.wikidata.org/entity/P569'), ('oName', 'date of birth')]

# 1) getting winners dob 
queryString = """

PREFIX xsd:  <http://www.w3.org/2001/XMLSchema#>
SELECT DISTINCT ?s ?sName ?pName ?o ?oName
WHERE {
   # ?s ?p ?o.
   # ?s sc:name ?sName.
   # ?p sc:name ?pName.
   # ?o sc:name ?oName.
   #it never returns the result if un-comment the filter
   #FILTER (?o > "1975"^^xsd:gYear)
}
LIMIT 10
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('s', 'http://www.wikidata.org/entity/Q95452024'), ('sName', 'Template:Vice Presidents of the Maldives'), ('pName', 'template has topic'), ('o', 'http://www.wikidata.org/entity/Q10999435'), ('oName', 'Vice President of the Maldives')]
# [('s', 'http://www.wikidata.org/entity/Q25752552'), ('sName', 'Template:2001 in Europe'), ('pName', 'template has topic'), ('o', 'http://www.wikidata.org/entity/Q17111750'), ('oName', '2001 in Europe')]
# [('s', 'http://www.wikidata.org/entity/Q6675314'), ('sName', 'Template:Alcest'), ('pName', 'template has topic'), ('o', 'http://www.wikidata.org/entity/Q1517060'), ('oName', 'Alcest')]
# [('s', 'http://www.wikidata.org/entity/Q22785857'), ('sName', 'Template:2006 in Europe'), ('pName', 'template has topic'), ('o', 'http://www.wikidata.org/entity/Q17111782'), ('oName', '2006 in Europe')]
# [('s', 'http://www.wikidata.org/entity/Q85816744'), ('sName', 'Yodli'), ('pName', 'represents'), ('o', 'http://www.wikidata.org/entity/Q1053559'), ('oName', '2020 Winter Youth Olympics')]
# [('s', 'http://www.wikidata.org/entity/Q1064606'), ('sName', 'President of the Maldives'), ('pName', 'substitute/deputy/replacement of office/officeholder'), ('o', 'http://www.wikidata.org/entity/Q10999435'), ('oName', 'Vice President of the Maldives')]
# [('s', 'http://www.wikidata.org/entity/Q10275776'), ('sName', 'Estação Ferroviária de Mafra'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q18483474'), ('sName', 'Telhada halt'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q8202323'), ('sName', 'Alcainça-Moinhos halt'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q8202353'), ('sName', 'Bicanho Halt'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# 10

# %%
# Consider the tennis players born after 1975, return who won more Grand Slams and cut the result to the top-10 (the result set must be a list of triples player IRI, label and #victories).
# Q1426 = Roger Federer
# wdt:P1344 (participant in)
# wdt:P2522 (victory)
#[('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('o', 'http://www.wikidata.org/entity/P569'), ('oName', 'date of birth')]

# 1) getting winners dob 
queryString = """

SELECT DISTINCT ?s ?sName ?p ?pName ?o ?oName
WHERE {
   # ?s ?p ?o.
   # ?s sc:name ?sName.
   # ?p sc:name ?pName.
   # ?o sc:name ?oName.
   FILTER (REGEX(?oName, "1975.*"))
   FILTER (?p != wdt:P155 && ?p != wdt:P301)
}
LIMIT 10
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('s', 'http://www.wikidata.org/entity/Q4574296'), ('sName', '1970s in Hong Kong'), ('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('o', 'http://www.wikidata.org/entity/Q15930131'), ('oName', '1975 in Hong Kong')]
# [('s', 'http://www.wikidata.org/entity/Q19568414'), ('sName', '1974 in Iran'), ('p', 'http://www.wikidata.org/prop/direct/P156'), ('pName', 'followed by'), ('o', 'http://www.wikidata.org/entity/Q20987712'), ('oName', '1975 in Iran')]
# [('s', 'http://www.wikidata.org/entity/Q19568417'), ('sName', '1974 in Kuwait'), ('p', 'http://www.wikidata.org/prop/direct/P156'), ('pName', 'followed by'), ('o', 'http://www.wikidata.org/entity/Q19568426'), ('oName', '1975 in Kuwait')]
# [('s', 'http://www.wikidata.org/entity/Q30731465'), ('sName', 'Category:1975 in Yugoslavian sport'), ('p', 'http://www.wikidata.org/prop/direct/P971'), ('pName', 'category combines topics'), ('o', 'http://www.wikidata.org/entity/Q1074111'), ('oName', '1975 in sports')]
# [('s', 'http://www.wikidata.org/entity/Q765955'), ('sName', '1974 in sports'), ('p', 'http://www.wikidata.org/prop/direct/P156'), ('pName', 'followed by'), ('o', 'http://www.wikidata.org/entity/Q1074111'), ('oName', '1975 in sports')]
# [('s', 'http://www.wikidata.org/entity/Q12780106'), ('sName', 'Category:1975 in Norwegian sport'), ('p', 'http://www.wikidata.org/prop/direct/P971'), ('pName', 'category combines topics'), ('o', 'http://www.wikidata.org/entity/Q1074111'), ('oName', '1975 in sports')]
# [('s', 'http://www.wikidata.org/entity/Q52194164'), ('sName', '1974 in Tunisia'), ('p', 'http://www.wikidata.org/prop/direct/P156'), ('pName', 'followed by'), ('o', 'http://www.wikidata.org/entity/Q52194165'), ('oName', '1975 in Tunisia')]
# [('s', 'http://www.wikidata.org/entity/Q4576321'), ('sName', '1974 in Denmark'), ('p', 'http://www.wikidata.org/prop/direct/P156'), ('pName', 'followed by'), ('o', 'http://www.wikidata.org/entity/Q4576876'), ('oName', '1975 in Denmark')]
# [('s', 'http://www.wikidata.org/entity/Q19839683'), ('sName', '1974 in Taiwan'), ('p', 'http://www.wikidata.org/prop/direct/P156'), ('pName', 'followed by'), ('o', 'http://www.wikidata.org/entity/Q4576919'), ('oName', '1975 in Taiwan')]
# [('s', 'http://www.wikidata.org/entity/Q8160342'), ('sName', 'Category:1975 in Swedish sport'), ('p', 'http://www.wikidata.org/prop/direct/P971'), ('pName', 'category combines topics'), ('o', 'http://www.wikidata.org/entity/Q1074111'), ('oName', '1975 in sports')]
# 10

# %%
# Consider the tennis players born after 1975, return who won more Grand Slams and cut the result to the top-10 (the result set must be a list of triples player IRI, label and #victories).
# Q1426 = Roger Federer
# wdt:P1344 (participant in)
# wdt:P2522 (victory)
#[('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('o', 'http://www.wikidata.org/entity/P569'), ('oName', 'date of birth')]

# 1) getting winners dob 
queryString = """

SELECT DISTINCT ?s ?sName ?p ?pName ?o ?oName
WHERE {
   # ?s ?p ?o.
   # ?s sc:name ?sName.
   # ?p sc:name ?pName.
   # ?o sc:name ?oName.
   
   #it never returns the result if un-comment the filter
   #FILTER (REGEX(?oName, "1981-08-08.*"))
   FILTER (?p NOT IN (wdt:P155,wdt:P301))
}
LIMIT 10
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('s', 'http://www.wikidata.org/entity/Q10275776'), ('sName', 'Estação Ferroviária de Mafra'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q11235194'), ('sName', 'Tokyo Solamachi'), ('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q11497641'), ('oName', 'Oshiage')]
# [('s', 'http://www.wikidata.org/entity/Q15628796'), ('sName', 'Pedro Ponce de Cabrera'), ('p', 'http://www.wikidata.org/prop/direct/P119'), ('pName', 'place of burial'), ('o', 'http://www.wikidata.org/entity/Q16608610'), ('oName', 'Monastery of Santa María de Nogales')]
# [('s', 'http://www.wikidata.org/entity/Q18483474'), ('sName', 'Telhada halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q18531652'), ('sName', 'William Walker'), ('p', 'http://www.wikidata.org/prop/direct/P1343'), ('pName', 'described by source'), ('o', 'http://www.wikidata.org/entity/Q17037575'), ('oName', 'Oxford Biography Index')]
# [('s', 'http://www.wikidata.org/entity/Q4829629'), ('sName', 'Awa-Ōmiya Station'), ('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q1350904'), ('oName', 'Itano')]
# [('s', 'http://www.wikidata.org/entity/Q7371392'), ('sName', 'Route 1'), ('p', 'http://www.wikidata.org/prop/direct/P126'), ('pName', 'maintained by'), ('o', 'http://www.wikidata.org/entity/Q11415304'), ('oName', 'Nagoya Expressway Public Corporation')]
# [('s', 'http://www.wikidata.org/entity/Q8134074'), ('sName', 'Sumida Aquarium'), ('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q11497641'), ('oName', 'Oshiage')]
# [('s', 'http://www.wikidata.org/entity/Q8146191'), ('sName', 'Nanga Pinoh'), ('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q14162'), ('oName', 'Melawi')]
# [('s', 'http://www.wikidata.org/entity/Q8167413'), ('sName', 'Guguak VIII Koto'), ('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q12403132'), ('oName', 'Guguak')]
# 10

# %%
# Consider the tennis players born after 1975, return who won more Grand Slams and cut the result to the top-10 (the result set must be a list of triples player IRI, label and #victories).
# Q1426 = Roger Federer
# wdt:P1344 (participant in)
# wdt:P2522 (victory)
#[('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('o', 'http://www.wikidata.org/entity/P569'), ('oName', 'date of birth')]

# 1) getting winners dob 
queryString = """

SELECT DISTINCT ?s ?sName ?p ?pName ?o ?oName
WHERE {
   # ?s ?p ?o.
   # ?s sc:name ?sName.
   # ?p sc:name ?pName.
   # ?o sc:name ?oName.
   
   #it never returns the result if un-comment the filter
   #FILTER (REGEX(?oName, "1981-08-0.*"))
}
LIMIT 1
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('s', 'http://www.wikidata.org/entity/Q95452024'), ('sName', 'Template:Vice Presidents of the Maldives'), ('p', 'http://www.wikidata.org/prop/direct/P1423'), ('pName', 'template has topic'), ('o', 'http://www.wikidata.org/entity/Q10999435'), ('oName', 'Vice President of the Maldives')]
# 1

# %%
# Consider the tennis players born after 1975, return who won more Grand Slams and cut the result to the top-10 (the result set must be a list of triples player IRI, label and #victories).
# Q1426 = Roger Federer
# wdt:P1344 (participant in)
# wdt:P2522 (victory)
#[('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('o', 'http://www.wikidata.org/entity/P569'), ('oName', 'date of birth')]

# 1) getting winners dob 
queryString = """

SELECT DISTINCT ?s ?sName ?p ?pName ?o ?oName
WHERE {
   # ?s ?p ?o.
   # ?s sc:name ?sName.
   # ?p sc:name ?pName.
   # ?o sc:name ?oName.
   FILTER (REGEX(?oName, "1981.*"))
}
LIMIT 10
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('s', 'http://www.wikidata.org/entity/Q8165395'), ('sName', 'Category:1982 elections in South America'), ('p', 'http://www.wikidata.org/prop/direct/P155'), ('pName', 'follows'), ('o', 'http://www.wikidata.org/entity/Q16772598'), ('oName', 'Category:1981 elections in South America')]
# [('s', 'http://www.wikidata.org/entity/Q15120431'), ('sName', 'Category:1982 in go'), ('p', 'http://www.wikidata.org/prop/direct/P155'), ('pName', 'follows'), ('o', 'http://www.wikidata.org/entity/Q15120313'), ('oName', 'Category:1981 in go')]
# [('s', 'http://www.wikidata.org/entity/Q8165681'), ('sName', 'Category:1982 in New Zealand sport'), ('p', 'http://www.wikidata.org/prop/direct/P155'), ('pName', 'follows'), ('o', 'http://www.wikidata.org/entity/Q11721574'), ('oName', 'Category:1981 in New Zealand sport')]
# [('s', 'http://www.wikidata.org/entity/Q52179909'), ('sName', '1982 in Finland'), ('p', 'http://www.wikidata.org/prop/direct/P155'), ('pName', 'follows'), ('o', 'http://www.wikidata.org/entity/Q62053918'), ('oName', '1981 in Finland')]
# [('s', 'http://www.wikidata.org/entity/Q2176147'), ('sName', '1982 in radio'), ('p', 'http://www.wikidata.org/prop/direct/P155'), ('pName', 'follows'), ('o', 'http://www.wikidata.org/entity/Q18027558'), ('oName', '1981 in radio')]
# [('s', 'http://www.wikidata.org/entity/Q4580698'), ('sName', '1982 in Bangladesh'), ('p', 'http://www.wikidata.org/prop/direct/P155'), ('pName', 'follows'), ('o', 'http://www.wikidata.org/entity/Q4580079'), ('oName', '1981 in Bangladesh')]
# [('s', 'http://www.wikidata.org/entity/Q19568493'), ('sName', '1982 in Iran'), ('p', 'http://www.wikidata.org/prop/direct/P155'), ('pName', 'follows'), ('o', 'http://www.wikidata.org/entity/Q19568484'), ('oName', '1981 in Iran')]
# [('s', 'http://www.wikidata.org/entity/Q8163328'), ('sName', 'Category:1980 elections in South America'), ('p', 'http://www.wikidata.org/prop/direct/P156'), ('pName', 'followed by'), ('o', 'http://www.wikidata.org/entity/Q16772598'), ('oName', 'Category:1981 elections in South America')]
# [('s', 'http://www.wikidata.org/entity/Q8163633'), ('sName', 'Category:1980 in New Zealand sport'), ('p', 'http://www.wikidata.org/prop/direct/P156'), ('pName', 'followed by'), ('o', 'http://www.wikidata.org/entity/Q11721574'), ('oName', 'Category:1981 in New Zealand sport')]
# [('s', 'http://www.wikidata.org/entity/Q2176145'), ('sName', '1980 in radio'), ('p', 'http://www.wikidata.org/prop/direct/P156'), ('pName', 'followed by'), ('o', 'http://www.wikidata.org/entity/Q18027558'), ('oName', '1981 in radio')]
# 10

# %%
# Consider the tennis players born after 1975, return who won more Grand Slams and cut the result to the top-10 (the result set must be a list of triples player IRI, label and #victories).
# Q1426 = Roger Federer
# wdt:P1344 (participant in)
# wdt:P2522 (victory)
#[('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('o', 'http://www.wikidata.org/entity/P569'), ('oName', 'date of birth')]

# 1) getting winners dob 
queryString = """

SELECT DISTINCT ?s ?sName ?p ?pName ?o ?oName
WHERE {
   # ?s ?p ?o.
   # ?s sc:name ?sName.
   # ?p sc:name ?pName.
   # ?o sc:name ?oName.
   FILTER (?oName = "1981")
}
LIMIT 10
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# Empty

# %%
# Consider the tennis players born after 1975, return who won more Grand Slams and cut the result to the top-10 (the result set must be a list of triples player IRI, label and #victories).
# Q1426 = Roger Federer
# wdt:P1344 (participant in)
# wdt:P2522 (victory)
#[('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('o', 'http://www.wikidata.org/entity/P569'), ('oName', 'date of birth')]
# 1) getting winners dob 
queryString = """

SELECT DISTINCT ?s ?sName ?p ?pName ?o ?oName
WHERE {
   # ?s ?p ?o.
   # ?s sc:name ?sName.
   # ?p sc:name ?pName.
   # ?o sc:name ?oName.
   FILTER (?oName = "1981-08")
}
LIMIT 10
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# Empty

# %%
# Consider the tennis players born after 1975, return who won more Grand Slams and cut the result to the top-10 (the result set must be a list of triples player IRI, label and #victories).
# Q1426 = Roger Federer
# wdt:P1344 (participant in)
# wdt:P2522 (victory)
#[('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('o', 'http://www.wikidata.org/entity/P569'), ('oName', 'date of birth')]
# 1) getting winners dob 
queryString = """

SELECT DISTINCT ?s ?sName ?p ?pName ?o ?oName
WHERE {
   # ?s ?p ?o.
   # ?s sc:name ?sName.
   # ?p sc:name ?pName.
   # ?o sc:name ?oName.
   FILTER (?oName = "1981-08-08")
}
LIMIT 10
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# Empty

# %%
# Consider the tennis players born after 1975, return who won more Grand Slams and cut the result to the top-10 (the result set must be a list of triples player IRI, label and #victories).
# Q1426 = Roger Federer
# wdt:P1344 (participant in)
# wdt:P2522 (victory)
#[('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('o', 'http://www.wikidata.org/entity/P569'), ('oName', 'date of birth')]
# 1) getting winners dob 
queryString = """

SELECT DISTINCT ?s ?sName ?p ?pName ?o ?oName
WHERE {
   # ?s ?p ?o.
   # ?s sc:name ?sName.
   # ?p sc:name ?pName.
   # ?o sc:name ?oName.
   FILTER (REGEX(?oName,"1987-.*"))
}
LIMIT 10
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('s', 'http://www.wikidata.org/entity/Q17027610'), ('sName', 'Remembering Christmas'), ('p', 'http://www.wikidata.org/prop/direct/P155'), ('pName', 'follows'), ('o', 'http://www.wikidata.org/entity/Q16953722'), ('oName', 'The Best of David Benoit 1987-1995')]
# [('s', 'http://www.wikidata.org/entity/Q16466348'), ('sName', 'Shaken Not Stirred'), ('p', 'http://www.wikidata.org/prop/direct/P156'), ('pName', 'followed by'), ('o', 'http://www.wikidata.org/entity/Q16953722'), ('oName', 'The Best of David Benoit 1987-1995')]
# [('s', 'http://www.wikidata.org/entity/Q34757794'), ('sName', 'Child labor and musculoskeletal disorders: the Pelotas (Brazil) epidemiological survey.'), ('p', 'http://www.wikidata.org/prop/direct/P2860'), ('pName', 'cites work'), ('o', 'http://www.wikidata.org/entity/Q24169399'), ('oName', 'Work-related injuries to Massachusetts teens, 1987-1990')]
# [('s', 'http://www.wikidata.org/entity/Q23910866'), ('sName', "Teen workers' exposures to occupational hazards and use of personal protective equipment"), ('p', 'http://www.wikidata.org/prop/direct/P2860'), ('pName', 'cites work'), ('o', 'http://www.wikidata.org/entity/Q24169399'), ('oName', 'Work-related injuries to Massachusetts teens, 1987-1990')]
# [('s', 'http://www.wikidata.org/entity/Q28384893'), ('sName', 'Labor and Related Injuries among Schoolchildren in Palestine: Findings from the National Study of Palestinian Schoolchildren (HBSC-WBG2006)'), ('p', 'http://www.wikidata.org/prop/direct/P2860'), ('pName', 'cites work'), ('o', 'http://www.wikidata.org/entity/Q24169399'), ('oName', 'Work-related injuries to Massachusetts teens, 1987-1990')]
# [('s', 'http://www.wikidata.org/entity/Q28396037'), ('sName', 'An ecological study of regional variation in work injuries among young workers.'), ('p', 'http://www.wikidata.org/prop/direct/P2860'), ('pName', 'cites work'), ('o', 'http://www.wikidata.org/entity/Q24169399'), ('oName', 'Work-related injuries to Massachusetts teens, 1987-1990')]
# [('s', 'http://www.wikidata.org/entity/Q45833345'), ('sName', 'Child labor and protecting young workers around the world. An introduction to this issue.'), ('p', 'http://www.wikidata.org/prop/direct/P2860'), ('pName', 'cites work'), ('o', 'http://www.wikidata.org/entity/Q24169399'), ('oName', 'Work-related injuries to Massachusetts teens, 1987-1990')]
# [('s', 'http://www.wikidata.org/entity/Q38366777'), ('sName', 'Epidemiology of work-related traumatic brain injury: a systematic review.'), ('p', 'http://www.wikidata.org/prop/direct/P2860'), ('pName', 'cites work'), ('o', 'http://www.wikidata.org/entity/Q24169399'), ('oName', 'Work-related injuries to Massachusetts teens, 1987-1990')]
# [('s', 'http://www.wikidata.org/entity/Q28393715'), ('sName', "Age related differences in work injuries and permanent impairment: a comparison of workers' compensation claims among adolescents, young adults, and adults"), ('p', 'http://www.wikidata.org/prop/direct/P2860'), ('pName', 'cites work'), ('o', 'http://www.wikidata.org/entity/Q24169399'), ('oName', 'Work-related injuries to Massachusetts teens, 1987-1990')]
# [('s', 'http://www.wikidata.org/entity/Q39651534'), ('sName', 'Occupational accidents among middle and high school students of the state of São Paulo, Brazil.'), ('p', 'http://www.wikidata.org/prop/direct/P2860'), ('pName', 'cites work'), ('o', 'http://www.wikidata.org/entity/Q24169399'), ('oName', 'Work-related injuries to Massachusetts teens, 1987-1990')]
# 10

# %%
# Consider the tennis players born after 1975, return who won more Grand Slams and cut the result to the top-10 (the result set must be a list of triples player IRI, label and #victories).
# Q1426 = Roger Federer
# wdt:P1344 (participant in)
# wdt:P2522 (victory)
#[('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('o', 'http://www.wikidata.org/entity/P569'), ('oName', 'date of birth')]
# 1) getting winners dob 
queryString = """

SELECT DISTINCT ?s ?sName ?p ?pName ?o ?oName
WHERE {
   # ?s ?p ?o.
   # ?s sc:name ?sName.
   # ?p sc:name ?pName.
   # ?o sc:name ?oName.
   
   
   #it never returns the result if un-comment the filter
   #FILTER (REGEX(?oName,"1987-05.*"))
}
LIMIT 10
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('s', 'http://www.wikidata.org/entity/Q95452024'), ('sName', 'Template:Vice Presidents of the Maldives'), ('p', 'http://www.wikidata.org/prop/direct/P1423'), ('pName', 'template has topic'), ('o', 'http://www.wikidata.org/entity/Q10999435'), ('oName', 'Vice President of the Maldives')]
# [('s', 'http://www.wikidata.org/entity/Q25752552'), ('sName', 'Template:2001 in Europe'), ('p', 'http://www.wikidata.org/prop/direct/P1423'), ('pName', 'template has topic'), ('o', 'http://www.wikidata.org/entity/Q17111750'), ('oName', '2001 in Europe')]
# [('s', 'http://www.wikidata.org/entity/Q6675314'), ('sName', 'Template:Alcest'), ('p', 'http://www.wikidata.org/prop/direct/P1423'), ('pName', 'template has topic'), ('o', 'http://www.wikidata.org/entity/Q1517060'), ('oName', 'Alcest')]
# [('s', 'http://www.wikidata.org/entity/Q22785857'), ('sName', 'Template:2006 in Europe'), ('p', 'http://www.wikidata.org/prop/direct/P1423'), ('pName', 'template has topic'), ('o', 'http://www.wikidata.org/entity/Q17111782'), ('oName', '2006 in Europe')]
# [('s', 'http://www.wikidata.org/entity/Q85816744'), ('sName', 'Yodli'), ('p', 'http://www.wikidata.org/prop/direct/P1268'), ('pName', 'represents'), ('o', 'http://www.wikidata.org/entity/Q1053559'), ('oName', '2020 Winter Youth Olympics')]
# [('s', 'http://www.wikidata.org/entity/Q1064606'), ('sName', 'President of the Maldives'), ('p', 'http://www.wikidata.org/prop/direct/P2098'), ('pName', 'substitute/deputy/replacement of office/officeholder'), ('o', 'http://www.wikidata.org/entity/Q10999435'), ('oName', 'Vice President of the Maldives')]
# [('s', 'http://www.wikidata.org/entity/Q10275776'), ('sName', 'Estação Ferroviária de Mafra'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q18483474'), ('sName', 'Telhada halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q8202323'), ('sName', 'Alcainça-Moinhos halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q8202353'), ('sName', 'Bicanho Halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# 10

# %%
# Consider the tennis players born after 1975, return who won more Grand Slams and cut the result to the top-10 (the result set must be a list of triples player IRI, label and #victories).
# Q1426 = Roger Federer
# wdt:P1344 (participant in)
# wdt:P2522 (victory)
#[('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('o', 'http://www.wikidata.org/entity/P569'), ('oName', 'date of birth')]
# 1) getting winners dob 

queryString = """

SELECT DISTINCT ?s ?sName ?p ?pName ?o ?oName
WHERE {
   # ?s ?p ?o.
   # ?s sc:name ?sName.
   # ?p sc:name ?pName.
   # ?o sc:name ?oName.
   
   FILTER (REGEX(?oName,"May 1987"))
}
LIMIT 10
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('s', 'http://www.wikidata.org/entity/Q9615411'), ('sName', 'Category:May 1987 events'), ('p', 'http://www.wikidata.org/prop/direct/P301'), ('pName', "category's main topic"), ('o', 'http://www.wikidata.org/entity/Q13072296'), ('oName', 'May 1987')]
# [('s', 'http://www.wikidata.org/entity/Q69297253'), ('sName', 'May 4, 1987'), ('p', 'http://www.wikidata.org/prop/direct/P361'), ('pName', 'part of'), ('o', 'http://www.wikidata.org/entity/Q13072296'), ('oName', 'May 1987')]
# [('s', 'http://www.wikidata.org/entity/Q69297267'), ('sName', 'May 16, 1987'), ('p', 'http://www.wikidata.org/prop/direct/P361'), ('pName', 'part of'), ('o', 'http://www.wikidata.org/entity/Q13072296'), ('oName', 'May 1987')]
# [('s', 'http://www.wikidata.org/entity/Q69297272'), ('sName', 'May 20, 1987'), ('p', 'http://www.wikidata.org/prop/direct/P361'), ('pName', 'part of'), ('o', 'http://www.wikidata.org/entity/Q13072296'), ('oName', 'May 1987')]
# [('s', 'http://www.wikidata.org/entity/Q69297268'), ('sName', 'May 17, 1987'), ('p', 'http://www.wikidata.org/prop/direct/P361'), ('pName', 'part of'), ('o', 'http://www.wikidata.org/entity/Q13072296'), ('oName', 'May 1987')]
# [('s', 'http://www.wikidata.org/entity/Q69297273'), ('sName', 'May 21, 1987'), ('p', 'http://www.wikidata.org/prop/direct/P361'), ('pName', 'part of'), ('o', 'http://www.wikidata.org/entity/Q13072296'), ('oName', 'May 1987')]
# [('s', 'http://www.wikidata.org/entity/Q69297274'), ('sName', 'May 22, 1987'), ('p', 'http://www.wikidata.org/prop/direct/P361'), ('pName', 'part of'), ('o', 'http://www.wikidata.org/entity/Q13072296'), ('oName', 'May 1987')]
# [('s', 'http://www.wikidata.org/entity/Q69297256'), ('sName', 'May 7, 1987'), ('p', 'http://www.wikidata.org/prop/direct/P361'), ('pName', 'part of'), ('o', 'http://www.wikidata.org/entity/Q13072296'), ('oName', 'May 1987')]
# [('s', 'http://www.wikidata.org/entity/Q69297264'), ('sName', 'May 14, 1987'), ('p', 'http://www.wikidata.org/prop/direct/P361'), ('pName', 'part of'), ('o', 'http://www.wikidata.org/entity/Q13072296'), ('oName', 'May 1987')]
# [('s', 'http://www.wikidata.org/entity/Q69297261'), ('sName', 'May 11, 1987'), ('p', 'http://www.wikidata.org/prop/direct/P361'), ('pName', 'part of'), ('o', 'http://www.wikidata.org/entity/Q13072296'), ('oName', 'May 1987')]
# 10

# %%
# Consider the tennis players born after 1975, return who won more Grand Slams and cut the result to the top-10 (the result set must be a list of triples player IRI, label and #victories).
# Q1426 = Roger Federer
# wdt:P1344 (participant in)
# wdt:P2522 (victory)
#[('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('o', 'http://www.wikidata.org/entity/P569'), ('oName', 'date of birth')]
# 1) getting winners dob 

queryString = """

SELECT DISTINCT ?s ?sName ?p ?pName ?o ?oName
WHERE {
   # ?s ?p ?o.
   # ?s sc:name ?sName.
   # ?p sc:name ?pName.
   # ?o sc:name ?oName.
   
   
   #it never returns the result if un-comment the filter
   #FILTER (REGEX(?oName,"May 22, 1987"))
}
LIMIT 10
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('s', 'http://www.wikidata.org/entity/Q95452024'), ('sName', 'Template:Vice Presidents of the Maldives'), ('p', 'http://www.wikidata.org/prop/direct/P1423'), ('pName', 'template has topic'), ('o', 'http://www.wikidata.org/entity/Q10999435'), ('oName', 'Vice President of the Maldives')]
# [('s', 'http://www.wikidata.org/entity/Q25752552'), ('sName', 'Template:2001 in Europe'), ('p', 'http://www.wikidata.org/prop/direct/P1423'), ('pName', 'template has topic'), ('o', 'http://www.wikidata.org/entity/Q17111750'), ('oName', '2001 in Europe')]
# [('s', 'http://www.wikidata.org/entity/Q6675314'), ('sName', 'Template:Alcest'), ('p', 'http://www.wikidata.org/prop/direct/P1423'), ('pName', 'template has topic'), ('o', 'http://www.wikidata.org/entity/Q1517060'), ('oName', 'Alcest')]
# [('s', 'http://www.wikidata.org/entity/Q22785857'), ('sName', 'Template:2006 in Europe'), ('p', 'http://www.wikidata.org/prop/direct/P1423'), ('pName', 'template has topic'), ('o', 'http://www.wikidata.org/entity/Q17111782'), ('oName', '2006 in Europe')]
# [('s', 'http://www.wikidata.org/entity/Q85816744'), ('sName', 'Yodli'), ('p', 'http://www.wikidata.org/prop/direct/P1268'), ('pName', 'represents'), ('o', 'http://www.wikidata.org/entity/Q1053559'), ('oName', '2020 Winter Youth Olympics')]
# [('s', 'http://www.wikidata.org/entity/Q1064606'), ('sName', 'President of the Maldives'), ('p', 'http://www.wikidata.org/prop/direct/P2098'), ('pName', 'substitute/deputy/replacement of office/officeholder'), ('o', 'http://www.wikidata.org/entity/Q10999435'), ('oName', 'Vice President of the Maldives')]
# [('s', 'http://www.wikidata.org/entity/Q10275776'), ('sName', 'Estação Ferroviária de Mafra'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q18483474'), ('sName', 'Telhada halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q8202323'), ('sName', 'Alcainça-Moinhos halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q8202353'), ('sName', 'Bicanho Halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# 10

# %%
# Consider the tennis players born after 1975, return who won more Grand Slams and cut the result to the top-10 (the result set must be a list of triples player IRI, label and #victories).
# Q1426 = Roger Federer
# wdt:P1344 (participant in)
# wdt:P2522 (victory)
#[('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('o', 'http://www.wikidata.org/entity/P569'), ('oName', 'date of birth')]
# 1) getting winners dob 

queryString = """

SELECT DISTINCT ?p ?pName ?o ?oName
WHERE {
   wd:Q69297274 ?p ?o.
   # ?p sc:name ?pName.
   # ?o sc:name ?oName.
}
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('o', 'http://www.wikidata.org/entity/Q47150325'), ('oName', 'calendar day of a given year')]
# [('p', 'http://www.wikidata.org/prop/direct/P2894'), ('pName', 'day of week'), ('o', 'http://www.wikidata.org/entity/Q130'), ('oName', 'Friday')]
# [('p', 'http://www.wikidata.org/prop/direct/P361'), ('pName', 'part of'), ('o', 'http://www.wikidata.org/entity/Q13072296'), ('oName', 'May 1987')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('o', 'http://www.wikidata.org/entity/Q2581'), ('oName', 'May 22')]
# 4

# %%
# Consider the tennis players born after 1975, return who won more Grand Slams and cut the result to the top-10 (the result set must be a list of triples player IRI, label and #victories).
# Q1426 = Roger Federer
# wdt:P1344 (participant in)
# wdt:P2522 (victory)
#[('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('o', 'http://www.wikidata.org/entity/P569'), ('oName', 'date of birth')]
# 1) getting winners dob 

queryString = """

SELECT DISTINCT ?s ?sName ?p ?pName
WHERE {
   # ?s ?p wd:Q69297274.
   # ?p sc:name ?pName.
   # ?s sc:name ?sName.
}
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# Empty

# %%
# Consider the tennis players born after 1975, return who won more Grand Slams and cut the result to the top-10 (the result set must be a list of triples player IRI, label and #victories).
# Q1426 = Roger Federer
# wdt:P1344 (participant in)
# wdt:P2522 (victory)
#[('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('o', 'http://www.wikidata.org/entity/P569'), ('oName', 'date of birth')]
# 1) getting winners dob 

queryString = """

SELECT DISTINCT ?p ?pName ?o ?oName
WHERE {
   wd:Q13072296 ?p ?o.
   # ?p sc:name ?pName.
   # ?o sc:name ?oName.
}
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('o', 'http://www.wikidata.org/entity/Q119'), ('oName', 'May')]
# [('p', 'http://www.wikidata.org/prop/direct/P361'), ('pName', 'part of'), ('o', 'http://www.wikidata.org/entity/Q2429'), ('oName', '1987')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('o', 'http://www.wikidata.org/entity/Q47018478'), ('oName', 'calendar month of a given year')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('o', 'http://www.wikidata.org/entity/Q66010148'), ('oName', 'month starting on Friday')]
# [('p', 'http://www.wikidata.org/prop/direct/P910'), ('pName', "topic's main category"), ('o', 'http://www.wikidata.org/entity/Q9615411'), ('oName', 'Category:May 1987 events')]
# 5

# %%
# Consider the tennis players born after 1975, return who won more Grand Slams and cut the result to the top-10 (the result set must be a list of triples player IRI, label and #victories).
# Q1426 = Roger Federer
# wdt:P1344 (participant in)
# wdt:P2522 (victory)
#[('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('o', 'http://www.wikidata.org/entity/P569'), ('oName', 'date of birth')]
# 1) getting winners dob 

queryString = """

SELECT DISTINCT ?p ?pName ?o ?oName
WHERE {
   wd:Q2429 ?p ?o.
   # ?p sc:name ?pName.
   # ?o sc:name ?oName.
}
LIMIT 50
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P361'), ('pName', 'part of'), ('o', 'http://www.wikidata.org/entity/Q34644'), ('oName', '1980s')]
# [('p', 'http://www.wikidata.org/prop/direct/P361'), ('pName', 'part of'), ('o', 'http://www.wikidata.org/entity/Q12138'), ('oName', 'Gregorian calendar')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('o', 'http://www.wikidata.org/entity/Q235690'), ('oName', 'common year starting and ending on Thursday')]
# [('p', 'http://www.wikidata.org/prop/direct/P361'), ('pName', 'part of'), ('o', 'http://www.wikidata.org/entity/Q25860'), ('oName', '2nd millennium')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('o', 'http://www.wikidata.org/entity/Q3186692'), ('oName', 'calendar year')]
# [('p', 'http://www.wikidata.org/prop/direct/P361'), ('pName', 'part of'), ('o', 'http://www.wikidata.org/entity/Q6927'), ('oName', '20th century')]
# [('p', 'http://www.wikidata.org/prop/direct/P156'), ('pName', 'followed by'), ('o', 'http://www.wikidata.org/entity/Q2426'), ('oName', '1988')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('o', 'http://www.wikidata.org/entity/Q16647466'), ('oName', 'June 1987')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('o', 'http://www.wikidata.org/entity/Q16676420'), ('oName', 'September 1987')]
# [('p', 'http://www.wikidata.org/prop/direct/P155'), ('pName', 'follows'), ('o', 'http://www.wikidata.org/entity/Q2430'), ('oName', '1986')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('o', 'http://www.wikidata.org/entity/Q2370317'), ('oName', 'January 1987')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('o', 'http://www.wikidata.org/entity/Q13070126'), ('oName', 'February 1987')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('o', 'http://www.wikidata.org/entity/Q13072296'), ('oName', 'May 1987')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('o', 'http://www.wikidata.org/entity/Q13067918'), ('oName', 'December 1987')]
# [('p', 'http://www.wikidata.org/prop/direct/P910'), ('pName', "topic's main category"), ('o', 'http://www.wikidata.org/entity/Q6938503'), ('oName', 'Category:1987')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('o', 'http://www.wikidata.org/entity/Q16667792'), ('oName', 'October 1987')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('o', 'http://www.wikidata.org/entity/Q13071495'), ('oName', 'March 1987')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('o', 'http://www.wikidata.org/entity/Q13080501'), ('oName', 'August 1987')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('o', 'http://www.wikidata.org/entity/Q16646980'), ('oName', 'July 1987')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('o', 'http://www.wikidata.org/entity/Q16667227'), ('oName', 'November 1987')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('o', 'http://www.wikidata.org/entity/Q2874562'), ('oName', 'April 1987')]
# [('p', 'http://www.wikidata.org/prop/direct/P1889'), ('pName', 'different from'), ('o', 'http://www.wikidata.org/entity/Q13143069'), ('oName', '1987')]
# [('p', 'http://www.wikidata.org/prop/direct/P460'), ('pName', 'said to be the same as'), ('o', 'http://www.wikidata.org/entity/Q108001662'), ('oName', '11987 HE')]
# 23

# %%
#BACKWARD YEAR 1987 = NOVAK DJOKOVIC (22 May 1987)

# %%
# Consider the tennis players born after 1975, return who won more Grand Slams and cut the result to the top-10 (the result set must be a list of triples player IRI, label and #victories).
# Q1426 = Roger Federer
# wdt:P1344 (participant in)
# wdt:P2522 (victory)
#[('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('o', 'http://www.wikidata.org/entity/P569'), ('oName', 'date of birth')]
# 1) getting winners dob 

queryString = """

SELECT DISTINCT ?s ?sName ?p ?pName
WHERE {
   # ?s ?p wd:Q2429.
   # ?p sc:name ?pName.
   # ?s sc:name ?sName.
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('s', 'http://www.wikidata.org/entity/Q1078784'), ('sName', '1987 in sports'), ('p', 'http://www.wikidata.org/prop/direct/P1269'), ('pName', 'facet of')]
# [('s', 'http://www.wikidata.org/entity/Q1187070'), ('sName', '1987 in science'), ('p', 'http://www.wikidata.org/prop/direct/P1269'), ('pName', 'facet of')]
# [('s', 'http://www.wikidata.org/entity/Q8168795'), ('sName', 'Category:1987 Big Ten Conference football season'), ('p', 'http://www.wikidata.org/prop/direct/P971'), ('pName', 'category combines topics')]
# [('s', 'http://www.wikidata.org/entity/Q8168888'), ('sName', 'Category:1987 controversies'), ('p', 'http://www.wikidata.org/prop/direct/P971'), ('pName', 'category combines topics')]
# [('s', 'http://www.wikidata.org/entity/Q8168902'), ('sName', 'Category:1987 crimes'), ('p', 'http://www.wikidata.org/prop/direct/P971'), ('pName', 'category combines topics')]
# [('s', 'http://www.wikidata.org/entity/Q8168903'), ('sName', 'Category:1987 disestablishments in Norway'), ('p', 'http://www.wikidata.org/prop/direct/P971'), ('pName', 'category combines topics')]
# [('s', 'http://www.wikidata.org/entity/Q8168908'), ('sName', 'Category:1987 disestablishments in the United States'), ('p', 'http://www.wikidata.org/prop/direct/P971'), ('pName', 'category combines topics')]
# [('s', 'http://www.wikidata.org/entity/Q8168913'), ('sName', 'Category:1987 elections in Africa'), ('p', 'http://www.wikidata.org/prop/direct/P971'), ('pName', 'category combines topics')]
# [('s', 'http://www.wikidata.org/entity/Q8168930'), ('sName', 'Category:1987 essays'), ('p', 'http://www.wikidata.org/prop/direct/P971'), ('pName', 'category combines topics')]
# [('s', 'http://www.wikidata.org/entity/Q8168933'), ('sName', 'Category:1987 establishments in Angola'), ('p', 'http://www.wikidata.org/prop/direct/P971'), ('pName', 'category combines topics')]
# [('s', 'http://www.wikidata.org/entity/Q8168949'), ('sName', 'Category:1987 establishments in Cyprus'), ('p', 'http://www.wikidata.org/prop/direct/P971'), ('pName', 'category combines topics')]
# [('s', 'http://www.wikidata.org/entity/Q8168951'), ('sName', 'Category:1987 establishments in Czechoslovakia'), ('p', 'http://www.wikidata.org/prop/direct/P971'), ('pName', 'category combines topics')]
# [('s', 'http://www.wikidata.org/entity/Q8168969'), ('sName', 'Category:1987 establishments in Italy'), ('p', 'http://www.wikidata.org/prop/direct/P971'), ('pName', 'category combines topics')]
# [('s', 'http://www.wikidata.org/entity/Q8168988'), ('sName', 'Category:1987 establishments in Nicaragua'), ('p', 'http://www.wikidata.org/prop/direct/P971'), ('pName', 'category combines topics')]
# [('s', 'http://www.wikidata.org/entity/Q8168990'), ('sName', 'Category:1987 establishments in Norway'), ('p', 'http://www.wikidata.org/prop/direct/P971'), ('pName', 'category combines topics')]
# [('s', 'http://www.wikidata.org/entity/Q8168994'), ('sName', 'Category:1987 establishments in Poland'), ('p', 'http://www.wikidata.org/prop/direct/P971'), ('pName', 'category combines topics')]
# [('s', 'http://www.wikidata.org/entity/Q8169041'), ('sName', 'Category:1987 in African sport'), ('p', 'http://www.wikidata.org/prop/direct/P971'), ('pName', 'category combines topics')]
# [('s', 'http://www.wikidata.org/entity/Q8169042'), ('sName', 'Category:1987 in Alabama'), ('p', 'http://www.wikidata.org/prop/direct/P971'), ('pName', 'category combines topics')]
# [('s', 'http://www.wikidata.org/entity/Q8169045'), ('sName', 'Category:1987 in Algeria'), ('p', 'http://www.wikidata.org/prop/direct/P971'), ('pName', 'category combines topics')]
# [('s', 'http://www.wikidata.org/entity/Q8169047'), ('sName', 'Category:1987 in Africa'), ('p', 'http://www.wikidata.org/prop/direct/P971'), ('pName', 'category combines topics')]
# [('s', 'http://www.wikidata.org/entity/Q8169052'), ('sName', 'Category:1987 in Antigua and Barbuda'), ('p', 'http://www.wikidata.org/prop/direct/P971'), ('pName', 'category combines topics')]
# [('s', 'http://www.wikidata.org/entity/Q8169061'), ('sName', 'Category:1987 in Asian sport'), ('p', 'http://www.wikidata.org/prop/direct/P971'), ('pName', 'category combines topics')]
# [('s', 'http://www.wikidata.org/entity/Q8169068'), ('sName', 'Category:1987 in Bangladesh'), ('p', 'http://www.wikidata.org/prop/direct/P971'), ('pName', 'category combines topics')]
# [('s', 'http://www.wikidata.org/entity/Q8169069'), ('sName', 'Category:1987 in Austrian sport'), ('p', 'http://www.wikidata.org/prop/direct/P971'), ('pName', 'category combines topics')]
# [('s', 'http://www.wikidata.org/entity/Q8169074'), ('sName', 'Category:1987 in Bhutan'), ('p', 'http://www.wikidata.org/prop/direct/P971'), ('pName', 'category combines topics')]
# [('s', 'http://www.wikidata.org/entity/Q8169090'), ('sName', 'Category:1987 in Belgium'), ('p', 'http://www.wikidata.org/prop/direct/P971'), ('pName', 'category combines topics')]
# [('s', 'http://www.wikidata.org/entity/Q8169097'), ('sName', 'Category:1987 in Canadian sports'), ('p', 'http://www.wikidata.org/prop/direct/P971'), ('pName', 'category combines topics')]
# [('s', 'http://www.wikidata.org/entity/Q8169101'), ('sName', 'Category:1987 in Caribbean sport'), ('p', 'http://www.wikidata.org/prop/direct/P971'), ('pName', 'category combines topics')]
# [('s', 'http://www.wikidata.org/entity/Q8169111'), ('sName', 'Category:1987 in Cuba'), ('p', 'http://www.wikidata.org/prop/direct/P971'), ('pName', 'category combines topics')]
# [('s', 'http://www.wikidata.org/entity/Q8169115'), ('sName', 'Category:1987 in Dutch sport'), ('p', 'http://www.wikidata.org/prop/direct/P971'), ('pName', 'category combines topics')]
# [('s', 'http://www.wikidata.org/entity/Q8169118'), ('sName', 'Category:1987 in East Germany'), ('p', 'http://www.wikidata.org/prop/direct/P971'), ('pName', 'category combines topics')]
# [('s', 'http://www.wikidata.org/entity/Q8169120'), ('sName', 'Category:1987 in English sport'), ('p', 'http://www.wikidata.org/prop/direct/P971'), ('pName', 'category combines topics')]
# [('s', 'http://www.wikidata.org/entity/Q8169121'), ('sName', 'Category:1987 in Estonia'), ('p', 'http://www.wikidata.org/prop/direct/P971'), ('pName', 'category combines topics')]
# [('s', 'http://www.wikidata.org/entity/Q8169137'), ('sName', 'Category:1987 in Finland'), ('p', 'http://www.wikidata.org/prop/direct/P971'), ('pName', 'category combines topics')]
# [('s', 'http://www.wikidata.org/entity/Q8169148'), ('sName', 'Category:1987 in Europe'), ('p', 'http://www.wikidata.org/prop/direct/P971'), ('pName', 'category combines topics')]
# [('s', 'http://www.wikidata.org/entity/Q8169152'), ('sName', 'Category:1987 in Hong Kong'), ('p', 'http://www.wikidata.org/prop/direct/P971'), ('pName', 'category combines topics')]
# [('s', 'http://www.wikidata.org/entity/Q8169153'), ('sName', 'Category:1987 in Hungary'), ('p', 'http://www.wikidata.org/prop/direct/P971'), ('pName', 'category combines topics')]
# [('s', 'http://www.wikidata.org/entity/Q8169173'), ('sName', 'Category:1987 in Kentucky'), ('p', 'http://www.wikidata.org/prop/direct/P971'), ('pName', 'category combines topics')]
# [('s', 'http://www.wikidata.org/entity/Q8169193'), ('sName', 'Category:1987 in Massachusetts'), ('p', 'http://www.wikidata.org/prop/direct/P971'), ('pName', 'category combines topics')]
# [('s', 'http://www.wikidata.org/entity/Q8169194'), ('sName', 'Category:1987 in Italy'), ('p', 'http://www.wikidata.org/prop/direct/P971'), ('pName', 'category combines topics')]
# [('s', 'http://www.wikidata.org/entity/Q8169199'), ('sName', 'Category:1987 in Montserrat'), ('p', 'http://www.wikidata.org/prop/direct/P971'), ('pName', 'category combines topics')]
# [('s', 'http://www.wikidata.org/entity/Q8169212'), ('sName', 'Category:1987 in Nicaragua'), ('p', 'http://www.wikidata.org/prop/direct/P971'), ('pName', 'category combines topics')]
# [('s', 'http://www.wikidata.org/entity/Q8169217'), ('sName', 'Category:1987 in North American sport'), ('p', 'http://www.wikidata.org/prop/direct/P971'), ('pName', 'category combines topics')]
# [('s', 'http://www.wikidata.org/entity/Q8169218'), ('sName', 'Category:1987 in Northern Ireland'), ('p', 'http://www.wikidata.org/prop/direct/P971'), ('pName', 'category combines topics')]
# [('s', 'http://www.wikidata.org/entity/Q8169220'), ('sName', 'Category:1987 in Oceanian sport'), ('p', 'http://www.wikidata.org/prop/direct/P971'), ('pName', 'category combines topics')]
# [('s', 'http://www.wikidata.org/entity/Q8169222'), ('sName', 'Category:1987 in Pakistani sport'), ('p', 'http://www.wikidata.org/prop/direct/P971'), ('pName', 'category combines topics')]
# [('s', 'http://www.wikidata.org/entity/Q8169230'), ('sName', 'Category:1987 in Oceania'), ('p', 'http://www.wikidata.org/prop/direct/P971'), ('pName', 'category combines topics')]
# [('s', 'http://www.wikidata.org/entity/Q8169234'), ('sName', 'Category:1987 in Poland'), ('p', 'http://www.wikidata.org/prop/direct/P971'), ('pName', 'category combines topics')]
# [('s', 'http://www.wikidata.org/entity/Q8169243'), ('sName', 'Category:1987 in South American football'), ('p', 'http://www.wikidata.org/prop/direct/P971'), ('pName', 'category combines topics')]
# [('s', 'http://www.wikidata.org/entity/Q8169244'), ('sName', 'Category:1987 in South American sport'), ('p', 'http://www.wikidata.org/prop/direct/P971'), ('pName', 'category combines topics')]
# [('s', 'http://www.wikidata.org/entity/Q8169250'), ('sName', 'Category:1987 in Sri Lankan sport'), ('p', 'http://www.wikidata.org/prop/direct/P971'), ('pName', 'category combines topics')]
# [('s', 'http://www.wikidata.org/entity/Q8169253'), ('sName', 'Category:1987 in Swaziland'), ('p', 'http://www.wikidata.org/prop/direct/P971'), ('pName', 'category combines topics')]
# [('s', 'http://www.wikidata.org/entity/Q8169263'), ('sName', 'Category:1987 in Tibet'), ('p', 'http://www.wikidata.org/prop/direct/P971'), ('pName', 'category combines topics')]
# [('s', 'http://www.wikidata.org/entity/Q8169273'), ('sName', 'Category:1987 in Vietnam'), ('p', 'http://www.wikidata.org/prop/direct/P971'), ('pName', 'category combines topics')]
# [('s', 'http://www.wikidata.org/entity/Q8169279'), ('sName', 'Category:1987 in Sweden'), ('p', 'http://www.wikidata.org/prop/direct/P971'), ('pName', 'category combines topics')]
# [('s', 'http://www.wikidata.org/entity/Q8169286'), ('sName', 'Category:1987 in alpine skiing'), ('p', 'http://www.wikidata.org/prop/direct/P971'), ('pName', 'category combines topics')]
# [('s', 'http://www.wikidata.org/entity/Q8169289'), ('sName', 'Category:1987 in archery'), ('p', 'http://www.wikidata.org/prop/direct/P971'), ('pName', 'category combines topics')]
# [('s', 'http://www.wikidata.org/entity/Q8169299'), ('sName', 'Category:1987 in camogie'), ('p', 'http://www.wikidata.org/prop/direct/P971'), ('pName', 'category combines topics')]
# [('s', 'http://www.wikidata.org/entity/Q8169300'), ('sName', 'Category:1987 in canoeing'), ('p', 'http://www.wikidata.org/prop/direct/P971'), ('pName', 'category combines topics')]
# [('s', 'http://www.wikidata.org/entity/Q8169312'), ('sName', 'Category:1987 in chess'), ('p', 'http://www.wikidata.org/prop/direct/P971'), ('pName', 'category combines topics')]
# [('s', 'http://www.wikidata.org/entity/Q8169315'), ('sName', 'Category:1987 in economics'), ('p', 'http://www.wikidata.org/prop/direct/P971'), ('pName', 'category combines topics')]
# [('s', 'http://www.wikidata.org/entity/Q8169320'), ('sName', 'Category:1987 in figure skating'), ('p', 'http://www.wikidata.org/prop/direct/P971'), ('pName', 'category combines topics')]
# [('s', 'http://www.wikidata.org/entity/Q8169321'), ('sName', 'Category:1987 in cycle racing'), ('p', 'http://www.wikidata.org/prop/direct/P971'), ('pName', 'category combines topics')]
# [('s', 'http://www.wikidata.org/entity/Q8169323'), ('sName', 'Category:1987 in golf'), ('p', 'http://www.wikidata.org/prop/direct/P971'), ('pName', 'category combines topics')]
# [('s', 'http://www.wikidata.org/entity/Q8169349'), ('sName', 'Category:1987 in shooting sports'), ('p', 'http://www.wikidata.org/prop/direct/P971'), ('pName', 'category combines topics')]
# [('s', 'http://www.wikidata.org/entity/Q8169359'), ('sName', 'Category:1987 in table tennis'), ('p', 'http://www.wikidata.org/prop/direct/P971'), ('pName', 'category combines topics')]
# [('s', 'http://www.wikidata.org/entity/Q8169367'), ('sName', 'Category:1987 in the Central African Republic'), ('p', 'http://www.wikidata.org/prop/direct/P971'), ('pName', 'category combines topics')]
# [('s', 'http://www.wikidata.org/entity/Q8169369'), ('sName', 'Category:1987 in the Dominican Republic'), ('p', 'http://www.wikidata.org/prop/direct/P971'), ('pName', 'category combines topics')]
# [('s', 'http://www.wikidata.org/entity/Q8169374'), ('sName', 'Category:1987 in the Maldives'), ('p', 'http://www.wikidata.org/prop/direct/P971'), ('pName', 'category combines topics')]
# [('s', 'http://www.wikidata.org/entity/Q8169378'), ('sName', 'Category:1987 in science'), ('p', 'http://www.wikidata.org/prop/direct/P971'), ('pName', 'category combines topics')]
# [('s', 'http://www.wikidata.org/entity/Q8169387'), ('sName', 'Category:1987 in transport'), ('p', 'http://www.wikidata.org/prop/direct/P971'), ('pName', 'category combines topics')]
# [('s', 'http://www.wikidata.org/entity/Q8169391'), ('sName', 'Category:1987 in weightlifting'), ('p', 'http://www.wikidata.org/prop/direct/P971'), ('pName', 'category combines topics')]
# [('s', 'http://www.wikidata.org/entity/Q8169398'), ('sName', 'Category:1987 in music'), ('p', 'http://www.wikidata.org/prop/direct/P971'), ('pName', 'category combines topics')]
# [('s', 'http://www.wikidata.org/entity/Q8169399'), ('sName', 'Category:1987 in the United Kingdom'), ('p', 'http://www.wikidata.org/prop/direct/P971'), ('pName', 'category combines topics')]
# [('s', 'http://www.wikidata.org/entity/Q8169405'), ('sName', 'Category:1987 pinball machines'), ('p', 'http://www.wikidata.org/prop/direct/P971'), ('pName', 'category combines topics')]
# [('s', 'http://www.wikidata.org/entity/Q8169415'), ('sName', 'Category:1987 rugby union tournaments for national teams'), ('p', 'http://www.wikidata.org/prop/direct/P971'), ('pName', 'category combines topics')]
# [('s', 'http://www.wikidata.org/entity/Q8169428'), ('sName', 'Category:1987 telenovelas'), ('p', 'http://www.wikidata.org/prop/direct/P971'), ('pName', 'category combines topics')]
# [('s', 'http://www.wikidata.org/entity/Q8169435'), ('sName', "Category:1987–88 Atlantic 10 Conference men's basketball season"), ('p', 'http://www.wikidata.org/prop/direct/P971'), ('pName', 'category combines topics')]
# [('s', 'http://www.wikidata.org/entity/Q8169446'), ('sName', 'Category:1987 in sports'), ('p', 'http://www.wikidata.org/prop/direct/P971'), ('pName', 'category combines topics')]
# [('s', 'http://www.wikidata.org/entity/Q8228363'), ('sName', 'Category:Airlines disestablished in 1987'), ('p', 'http://www.wikidata.org/prop/direct/P971'), ('pName', 'category combines topics')]
# [('s', 'http://www.wikidata.org/entity/Q9737969'), ('sName', 'Category:1987 in Latvia'), ('p', 'http://www.wikidata.org/prop/direct/P971'), ('pName', 'category combines topics')]
# [('s', 'http://www.wikidata.org/entity/Q25304746'), ('sName', 'Category:Computer companies established in 1987'), ('p', 'http://www.wikidata.org/prop/direct/P971'), ('pName', 'category combines topics')]
# [('s', 'http://www.wikidata.org/entity/Q8414113'), ('sName', 'Category:Energy infrastructure completed in 1987'), ('p', 'http://www.wikidata.org/prop/direct/P971'), ('pName', 'category combines topics')]
# [('s', 'http://www.wikidata.org/entity/Q8627213'), ('sName', 'Category:Railway locomotives introduced in 1987'), ('p', 'http://www.wikidata.org/prop/direct/P971'), ('pName', 'category combines topics')]
# [('s', 'http://www.wikidata.org/entity/Q8631287'), ('sName', 'Category:Military units and formations disestablished in 1987'), ('p', 'http://www.wikidata.org/prop/direct/P971'), ('pName', 'category combines topics')]
# [('s', 'http://www.wikidata.org/entity/Q8651225'), ('sName', 'Category:Religious organizations established in 1987'), ('p', 'http://www.wikidata.org/prop/direct/P971'), ('pName', 'category combines topics')]
# [('s', 'http://www.wikidata.org/entity/Q8657975'), ('sName', 'Category:Restaurants established in 1987'), ('p', 'http://www.wikidata.org/prop/direct/P971'), ('pName', 'category combines topics')]
# [('s', 'http://www.wikidata.org/entity/Q8658956'), ('sName', 'Category:Retail companies established in 1987'), ('p', 'http://www.wikidata.org/prop/direct/P971'), ('pName', 'category combines topics')]
# [('s', 'http://www.wikidata.org/entity/Q17476912'), ('sName', 'Category:1987 in Indian cricket'), ('p', 'http://www.wikidata.org/prop/direct/P971'), ('pName', 'category combines topics')]
# [('s', 'http://www.wikidata.org/entity/Q8169181'), ('sName', 'Category:1987 in Lithuania'), ('p', 'http://www.wikidata.org/prop/direct/P971'), ('pName', 'category combines topics')]
# [('s', 'http://www.wikidata.org/entity/Q8169262'), ('sName', 'Category:1987 in Taiwan'), ('p', 'http://www.wikidata.org/prop/direct/P971'), ('pName', 'category combines topics')]
# [('s', 'http://www.wikidata.org/entity/Q19330371'), ('sName', 'Category:1987 disestablishments in Hawaii'), ('p', 'http://www.wikidata.org/prop/direct/P971'), ('pName', 'category combines topics')]
# [('s', 'http://www.wikidata.org/entity/Q8168910'), ('sName', 'Category:1987 compilation albums'), ('p', 'http://www.wikidata.org/prop/direct/P971'), ('pName', 'category combines topics')]
# [('s', 'http://www.wikidata.org/entity/Q7479617'), ('sName', 'Category:1987 treaties'), ('p', 'http://www.wikidata.org/prop/direct/P971'), ('pName', 'category combines topics')]
# [('s', 'http://www.wikidata.org/entity/Q1488064'), ('sName', '1987 in law'), ('p', 'http://www.wikidata.org/prop/direct/P1269'), ('pName', 'facet of')]
# [('s', 'http://www.wikidata.org/entity/Q2812957'), ('sName', '1987 in Canada'), ('p', 'http://www.wikidata.org/prop/direct/P1269'), ('pName', 'facet of')]
# [('s', 'http://www.wikidata.org/entity/Q2812969'), ('sName', '1987 in basketball'), ('p', 'http://www.wikidata.org/prop/direct/P1269'), ('pName', 'facet of')]
# [('s', 'http://www.wikidata.org/entity/Q2812973'), ('sName', '1987 in computer science'), ('p', 'http://www.wikidata.org/prop/direct/P1269'), ('pName', 'facet of')]
# [('s', 'http://www.wikidata.org/entity/Q2812974'), ('sName', '1987 in photography'), ('p', 'http://www.wikidata.org/prop/direct/P1269'), ('pName', 'facet of')]
# [('s', 'http://www.wikidata.org/entity/Q2812979'), ('sName', '1987 in sociology'), ('p', 'http://www.wikidata.org/prop/direct/P1269'), ('pName', 'facet of')]
# 100

# %%
# Consider the tennis players born after 1975, return who won more Grand Slams and cut the result to the top-10 (the result set must be a list of triples player IRI, label and #victories).
# Q1426 = Roger Federer
# wdt:P1344 (participant in)
# wdt:P2522 (victory)
#[('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('o', 'http://www.wikidata.org/entity/P569'), ('oName', 'date of birth')]
# 1) getting winners dob 

queryString = """

SELECT DISTINCT ?s ?sName ?p ?pName
WHERE {
   # ?s ?p wd:Q1078784.
   # ?p sc:name ?pName.
   # ?s sc:name ?sName.
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('s', 'http://www.wikidata.org/entity/Q1191213'), ('sName', '1986 in sports'), ('p', 'http://www.wikidata.org/prop/direct/P156'), ('pName', 'followed by')]
# [('s', 'http://www.wikidata.org/entity/Q8169053'), ('sName', 'Category:1987 in American sports'), ('p', 'http://www.wikidata.org/prop/direct/P971'), ('pName', 'category combines topics')]
# [('s', 'http://www.wikidata.org/entity/Q8169446'), ('sName', 'Category:1987 in sports'), ('p', 'http://www.wikidata.org/prop/direct/P301'), ('pName', "category's main topic")]
# [('s', 'http://www.wikidata.org/entity/Q8169255'), ('sName', 'Category:1987 in Swiss sport'), ('p', 'http://www.wikidata.org/prop/direct/P971'), ('pName', 'category combines topics')]
# [('s', 'http://www.wikidata.org/entity/Q301591'), ('sName', '1988 in sports'), ('p', 'http://www.wikidata.org/prop/direct/P155'), ('pName', 'follows')]
# [('s', 'http://www.wikidata.org/entity/Q8169254'), ('sName', 'Category:1987 in Swedish sport'), ('p', 'http://www.wikidata.org/prop/direct/P971'), ('pName', 'category combines topics')]
# [('s', 'http://www.wikidata.org/entity/Q32381384'), ('sName', 'Category:1987 in Sammarinese sport'), ('p', 'http://www.wikidata.org/prop/direct/P971'), ('pName', 'category combines topics')]
# [('s', 'http://www.wikidata.org/entity/Q30731474'), ('sName', 'Category:1987 in Yugoslavian sport'), ('p', 'http://www.wikidata.org/prop/direct/P971'), ('pName', 'category combines topics')]
# [('s', 'http://www.wikidata.org/entity/Q13240149'), ('sName', 'Category:1987 in Norwegian sport'), ('p', 'http://www.wikidata.org/prop/direct/P971'), ('pName', 'category combines topics')]
# 9

# %%
# Consider the tennis players born after 1975, return who won more Grand Slams and cut the result to the top-10 (the result set must be a list of triples player IRI, label and #victories).
# Q1426 = Roger Federer
# wdt:P1344 (participant in)
# wdt:P2522 (victory)
#[('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('o', 'http://www.wikidata.org/entity/P569'), ('oName', 'date of birth')]
# 1) getting winners dob 

queryString = """

SELECT DISTINCT ?p ?pName ?o ?oName
WHERE {
   wd:Q1078784 ?p ?o.
   # ?p sc:name ?pName.
   # ?o sc:name ?oName.
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P155'), ('pName', 'follows'), ('o', 'http://www.wikidata.org/entity/Q1191213'), ('oName', '1986 in sports')]
# [('p', 'http://www.wikidata.org/prop/direct/P910'), ('pName', "topic's main category"), ('o', 'http://www.wikidata.org/entity/Q8169446'), ('oName', 'Category:1987 in sports')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('o', 'http://www.wikidata.org/entity/Q18340514'), ('oName', 'events in a specific year or time period')]
# [('p', 'http://www.wikidata.org/prop/direct/P1269'), ('pName', 'facet of'), ('o', 'http://www.wikidata.org/entity/Q349'), ('oName', 'sport')]
# [('p', 'http://www.wikidata.org/prop/direct/P1269'), ('pName', 'facet of'), ('o', 'http://www.wikidata.org/entity/Q2429'), ('oName', '1987')]
# [('p', 'http://www.wikidata.org/prop/direct/P156'), ('pName', 'followed by'), ('o', 'http://www.wikidata.org/entity/Q301591'), ('oName', '1988 in sports')]
# 6

# %%
# Consider the tennis players born after 1975, return who won more Grand Slams and cut the result to the top-10 (the result set must be a list of triples player IRI, label and #victories).
# Q1426 = Roger Federer
# wdt:P1344 (participant in)
# wdt:P2522 (victory)
#[('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('o', 'http://www.wikidata.org/entity/P569'), ('oName', 'date of birth')]
# 1) getting winners dob 

queryString = """

SELECT DISTINCT ?s ?sName ?p ?pName ?o ?oName
WHERE {
   # ?s ?p ?o.
   # ?s sc:name ?sName.
   # ?p sc:name ?pName.
   # ?o sc:name ?oName.
   
   # SOMETIMES WORKS, sometimes doesn't return any result
   # FILTER (REGEX(?pName,"[B|b]irth*"))
   #FILTER (?p not in (wdt:P19))
}
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# The operation failed timed out

# %%
# Consider the tennis players born after 1975, return who won more Grand Slams and cut the result to the top-10 (the result set must be a list of triples player IRI, label and #victories).
# Q1426 = Roger Federer
# wdt:P1344 (participant in)
# wdt:P2522 (victory)
#[('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('o', 'http://www.wikidata.org/entity/P569'), ('oName', 'date of birth')]
# 1) getting winners dob 

queryString = """

SELECT DISTINCT ?s ?sName ?p ?pName ?o ?oName
WHERE {
   # ?s ?p ?o.
   # ?s sc:name ?sName.
   # ?p sc:name ?pName.
   # ?o sc:name ?oName.
   
   #it never returns the result if un-comment the filter
   #FILTER (REGEX(?pName,"[B|b]irth*"))
   FILTER (?p not in (wdt:P19))
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('s', 'http://www.wikidata.org/entity/Q10275776'), ('sName', 'Estação Ferroviária de Mafra'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q11235194'), ('sName', 'Tokyo Solamachi'), ('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q11497641'), ('oName', 'Oshiage')]
# [('s', 'http://www.wikidata.org/entity/Q15628796'), ('sName', 'Pedro Ponce de Cabrera'), ('p', 'http://www.wikidata.org/prop/direct/P119'), ('pName', 'place of burial'), ('o', 'http://www.wikidata.org/entity/Q16608610'), ('oName', 'Monastery of Santa María de Nogales')]
# [('s', 'http://www.wikidata.org/entity/Q18483474'), ('sName', 'Telhada halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q18531652'), ('sName', 'William Walker'), ('p', 'http://www.wikidata.org/prop/direct/P1343'), ('pName', 'described by source'), ('o', 'http://www.wikidata.org/entity/Q17037575'), ('oName', 'Oxford Biography Index')]
# [('s', 'http://www.wikidata.org/entity/Q4829629'), ('sName', 'Awa-Ōmiya Station'), ('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q1350904'), ('oName', 'Itano')]
# [('s', 'http://www.wikidata.org/entity/Q7371392'), ('sName', 'Route 1'), ('p', 'http://www.wikidata.org/prop/direct/P126'), ('pName', 'maintained by'), ('o', 'http://www.wikidata.org/entity/Q11415304'), ('oName', 'Nagoya Expressway Public Corporation')]
# [('s', 'http://www.wikidata.org/entity/Q8134074'), ('sName', 'Sumida Aquarium'), ('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q11497641'), ('oName', 'Oshiage')]
# [('s', 'http://www.wikidata.org/entity/Q8146191'), ('sName', 'Nanga Pinoh'), ('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q14162'), ('oName', 'Melawi')]
# [('s', 'http://www.wikidata.org/entity/Q8167413'), ('sName', 'Guguak VIII Koto'), ('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q12403132'), ('oName', 'Guguak')]
# [('s', 'http://www.wikidata.org/entity/Q8183600'), ('sName', 'Agrostroj Pelhřimov'), ('p', 'http://www.wikidata.org/prop/direct/P127'), ('pName', 'owned by'), ('o', 'http://www.wikidata.org/entity/Q100343342'), ('oName', 'Lubomír Stoklásek')]
# [('s', 'http://www.wikidata.org/entity/Q8183671'), ('sName', 'Aarão de Lacerda'), ('p', 'http://www.wikidata.org/prop/direct/P108'), ('pName', 'employer'), ('o', 'http://www.wikidata.org/entity/Q10279508'), ('oName', 'Faculdade de Letras da Universidade de Coimbra')]
# [('s', 'http://www.wikidata.org/entity/Q8183671'), ('sName', 'Aarão de Lacerda'), ('p', 'http://www.wikidata.org/prop/direct/P108'), ('pName', 'employer'), ('o', 'http://www.wikidata.org/entity/Q10279509'), ('oName', 'Faculty of Arts and Humanities of the University of Porto')]
# [('s', 'http://www.wikidata.org/entity/Q8190594'), ('sName', 'Awa-Kawabata Station'), ('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q1350904'), ('oName', 'Itano')]
# [('s', 'http://www.wikidata.org/entity/Q8190673'), ('sName', 'Itano Station'), ('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q1350904'), ('oName', 'Itano')]
# [('s', 'http://www.wikidata.org/entity/Q8190939'), ('sName', 'Calaf-Salavinera Airport'), ('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q15967'), ('oName', 'Sant Pere Sallavinera')]
# [('s', 'http://www.wikidata.org/entity/Q8194022'), ('sName', 'Tomonoura'), ('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q17238551'), ('oName', 'Tomo')]
# [('s', 'http://www.wikidata.org/entity/Q8195084'), ('sName', 'mahjong tile'), ('p', 'http://www.wikidata.org/prop/direct/P1269'), ('pName', 'facet of'), ('o', 'http://www.wikidata.org/entity/Q12263'), ('oName', 'mahjong')]
# [('s', 'http://www.wikidata.org/entity/Q8197013'), ('sName', 'Amancio Muñoz de Zafra'), ('p', 'http://www.wikidata.org/prop/direct/P1038'), ('pName', 'relative'), ('o', 'http://www.wikidata.org/entity/Q105753880'), ('oName', 'Mateo Egea')]
# [('s', 'http://www.wikidata.org/entity/Q8199438'), ('sName', 'Andrés de Sola'), ('p', 'http://www.wikidata.org/prop/direct/P1066'), ('pName', 'student of'), ('o', 'http://www.wikidata.org/entity/Q11686949'), ('oName', 'José Ximénez')]
# [('s', 'http://www.wikidata.org/entity/Q8200247'), ('sName', 'Annette Aiello'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('pName', 'occupation'), ('o', 'http://www.wikidata.org/entity/Q12368980'), ('oName', 'nature photographer')]
# [('s', 'http://www.wikidata.org/entity/Q8200247'), ('sName', 'Annette Aiello'), ('p', 'http://www.wikidata.org/prop/direct/P108'), ('pName', 'employer'), ('o', 'http://www.wikidata.org/entity/Q1673980'), ('oName', 'Smithsonian Tropical Research Institute')]
# [('s', 'http://www.wikidata.org/entity/Q8200777'), ('sName', 'Anthony Walker'), ('p', 'http://www.wikidata.org/prop/direct/P1343'), ('pName', 'described by source'), ('o', 'http://www.wikidata.org/entity/Q17037575'), ('oName', 'Oxford Biography Index')]
# [('s', 'http://www.wikidata.org/entity/Q8202323'), ('sName', 'Alcainça-Moinhos halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q8202353'), ('sName', 'Bicanho Halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q8213303'), ('sName', 'Bunguran Utara'), ('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q10100'), ('oName', 'Natuna')]
# [('s', 'http://www.wikidata.org/entity/Q8779275'), ('sName', 'Amieira train station'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q8841005'), ('sName', 'Malveira train station'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q95452024'), ('sName', 'Template:Vice Presidents of the Maldives'), ('p', 'http://www.wikidata.org/prop/direct/P1423'), ('pName', 'template has topic'), ('o', 'http://www.wikidata.org/entity/Q10999435'), ('oName', 'Vice President of the Maldives')]
# [('s', 'http://www.wikidata.org/entity/Q81904264'), ('sName', 'Kim Ji-min'), ('p', 'http://www.wikidata.org/prop/direct/P1344'), ('pName', 'participant in'), ('o', 'http://www.wikidata.org/entity/Q1053559'), ('oName', '2020 Winter Youth Olympics')]
# [('s', 'http://www.wikidata.org/entity/Q17211428'), ('sName', 'Shigahondōri, Nagoya'), ('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q1207964'), ('oName', 'Kita-ku')]
# [('s', 'http://www.wikidata.org/entity/Q17218089'), ('sName', 'Shimmei-chō, Nagoya'), ('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q1207964'), ('oName', 'Kita-ku')]
# [('s', 'http://www.wikidata.org/entity/Q17222169'), ('sName', 'Yanagihara, Nagoya'), ('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q1207964'), ('oName', 'Kita-ku')]
# [('s', 'http://www.wikidata.org/entity/Q17228019'), ('sName', 'Onari-tōri, Nagoya'), ('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q1207964'), ('oName', 'Kita-ku')]
# [('s', 'http://www.wikidata.org/entity/Q17482735'), ('sName', 'Turó de Montcortal'), ('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q13010'), ('oName', 'Arbúcies')]
# [('s', 'http://www.wikidata.org/entity/Q17482780'), ('sName', 'Turó de Montsoriu'), ('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q13010'), ('oName', 'Arbúcies')]
# [('s', 'http://www.wikidata.org/entity/Q17588022'), ('sName', 'Bassa de la Farga'), ('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q13010'), ('oName', 'Arbúcies')]
# [('s', 'http://www.wikidata.org/entity/Q17614805'), ('sName', 'muntanya de Can Fonoll'), ('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q13010'), ('oName', 'Arbúcies')]
# [('s', 'http://www.wikidata.org/entity/Q5289551'), ('sName', 'Dolores Piperno'), ('p', 'http://www.wikidata.org/prop/direct/P108'), ('pName', 'employer'), ('o', 'http://www.wikidata.org/entity/Q1673980'), ('oName', 'Smithsonian Tropical Research Institute')]
# [('s', 'http://www.wikidata.org/entity/Q91336419'), ('sName', 'Tommy Merlyn'), ('p', 'http://www.wikidata.org/prop/direct/P119'), ('pName', 'place of burial'), ('o', 'http://www.wikidata.org/entity/Q1419655'), ('oName', 'Star City')]
# [('s', 'http://www.wikidata.org/entity/Q91376977'), ('sName', 'Monica Munoz-Torres'), ('p', 'http://www.wikidata.org/prop/direct/P108'), ('pName', 'employer'), ('o', 'http://www.wikidata.org/entity/Q1673980'), ('oName', 'Smithsonian Tropical Research Institute')]
# [('s', 'http://www.wikidata.org/entity/Q30902089'), ('sName', 'Luis Manuel Fernández'), ('p', 'http://www.wikidata.org/prop/direct/P108'), ('pName', 'employer'), ('o', 'http://www.wikidata.org/entity/Q1475831'), ('oName', 'Venezolana de Televisión')]
# [('s', 'http://www.wikidata.org/entity/Q60684635'), ('sName', 'S. Joseph Wright'), ('p', 'http://www.wikidata.org/prop/direct/P108'), ('pName', 'employer'), ('o', 'http://www.wikidata.org/entity/Q1673980'), ('oName', 'Smithsonian Tropical Research Institute')]
# [('s', 'http://www.wikidata.org/entity/Q38780585'), ('sName', 'First Minister of British Honduras'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q1643555'), ('oName', 'British Honduras')]
# [('s', 'http://www.wikidata.org/entity/Q11325962'), ('sName', 'Hyatt Regency Kyoto'), ('p', 'http://www.wikidata.org/prop/direct/P127'), ('pName', 'owned by'), ('o', 'http://www.wikidata.org/entity/Q11292651'), ('oName', 'Orix Real Estate')]
# [('s', 'http://www.wikidata.org/entity/Q18527476'), ('sName', 'David Brown'), ('p', 'http://www.wikidata.org/prop/direct/P1343'), ('pName', 'described by source'), ('o', 'http://www.wikidata.org/entity/Q17037575'), ('oName', 'Oxford Biography Index')]
# [('s', 'http://www.wikidata.org/entity/Q10863554'), ('sName', 'Ryūgasaki Domain'), ('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q1055353'), ('oName', 'Hitachi Province')]
# [('s', 'http://www.wikidata.org/entity/Q18005572'), ('sName', "Serra d'en Pere Bord"), ('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q13010'), ('oName', 'Arbúcies')]
# [('s', 'http://www.wikidata.org/entity/Q18529777'), ('sName', 'James Brown'), ('p', 'http://www.wikidata.org/prop/direct/P1343'), ('pName', 'described by source'), ('o', 'http://www.wikidata.org/entity/Q17037575'), ('oName', 'Oxford Biography Index')]
# [('s', 'http://www.wikidata.org/entity/Q18530178'), ('sName', 'John Brown'), ('p', 'http://www.wikidata.org/prop/direct/P1343'), ('pName', 'described by source'), ('o', 'http://www.wikidata.org/entity/Q17037575'), ('oName', 'Oxford Biography Index')]
# [('s', 'http://www.wikidata.org/entity/Q18810862'), ('sName', 'John Robinson'), ('p', 'http://www.wikidata.org/prop/direct/P1343'), ('pName', 'described by source'), ('o', 'http://www.wikidata.org/entity/Q17037575'), ('oName', 'Oxford Biography Index')]
# [('s', 'http://www.wikidata.org/entity/Q18810881'), ('sName', 'John Merry Ross'), ('p', 'http://www.wikidata.org/prop/direct/P1343'), ('pName', 'described by source'), ('o', 'http://www.wikidata.org/entity/Q17037575'), ('oName', 'Oxford Biography Index')]
# [('s', 'http://www.wikidata.org/entity/Q21338376'), ('sName', 'George R. Angehr'), ('p', 'http://www.wikidata.org/prop/direct/P108'), ('pName', 'employer'), ('o', 'http://www.wikidata.org/entity/Q1673980'), ('oName', 'Smithsonian Tropical Research Institute')]
# [('s', 'http://www.wikidata.org/entity/Q108386354'), ('sName', 'William P. Leonard'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('pName', 'occupation'), ('o', 'http://www.wikidata.org/entity/Q12368980'), ('oName', 'nature photographer')]
# [('s', 'http://www.wikidata.org/entity/Q64910919'), ('sName', 'Subish Palaian'), ('p', 'http://www.wikidata.org/prop/direct/P108'), ('pName', 'employer'), ('o', 'http://www.wikidata.org/entity/Q12204508'), ('oName', 'Ajman University')]
# [('s', 'http://www.wikidata.org/entity/Q57161562'), ('sName', 'Michiel van Breugel'), ('p', 'http://www.wikidata.org/prop/direct/P108'), ('pName', 'employer'), ('o', 'http://www.wikidata.org/entity/Q1673980'), ('oName', 'Smithsonian Tropical Research Institute')]
# [('s', 'http://www.wikidata.org/entity/Q76449094'), ('sName', 'Victoria Stirnemann'), ('p', 'http://www.wikidata.org/prop/direct/P1344'), ('pName', 'participant in'), ('o', 'http://www.wikidata.org/entity/Q1053559'), ('oName', '2020 Winter Youth Olympics')]
# [('s', 'http://www.wikidata.org/entity/Q81904099'), ('sName', 'Benjamin Kapp'), ('p', 'http://www.wikidata.org/prop/direct/P1344'), ('pName', 'participant in'), ('o', 'http://www.wikidata.org/entity/Q1053559'), ('oName', '2020 Winter Youth Olympics')]
# [('s', 'http://www.wikidata.org/entity/Q1749545'), ('sName', 'Nova Zagora Municipality'), ('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q113120'), ('oName', 'Sliven Province')]
# [('s', 'http://www.wikidata.org/entity/Q3031457'), ('sName', 'Mananjary'), ('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q1462671'), ('oName', 'Vatovavy-Fitovinany')]
# [('s', 'http://www.wikidata.org/entity/Q7850092'), ('sName', 'Tsukuba district'), ('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q1055353'), ('oName', 'Hitachi Province')]
# [('s', 'http://www.wikidata.org/entity/Q24232048'), ('sName', 'Pulau Tiga Barat'), ('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q10100'), ('oName', 'Natuna')]
# [('s', 'http://www.wikidata.org/entity/Q8213242'), ('sName', 'Pulau Tiga'), ('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q10100'), ('oName', 'Natuna')]
# [('s', 'http://www.wikidata.org/entity/Q18526878'), ('sName', 'John Evans'), ('p', 'http://www.wikidata.org/prop/direct/P1343'), ('pName', 'described by source'), ('o', 'http://www.wikidata.org/entity/Q17037575'), ('oName', 'Oxford Biography Index')]
# [('s', 'http://www.wikidata.org/entity/Q18527381'), ('sName', 'John Murray'), ('p', 'http://www.wikidata.org/prop/direct/P1343'), ('pName', 'described by source'), ('o', 'http://www.wikidata.org/entity/Q17037575'), ('oName', 'Oxford Biography Index')]
# [('s', 'http://www.wikidata.org/entity/Q18527772'), ('sName', 'John Walker'), ('p', 'http://www.wikidata.org/prop/direct/P1343'), ('pName', 'described by source'), ('o', 'http://www.wikidata.org/entity/Q17037575'), ('oName', 'Oxford Biography Index')]
# [('s', 'http://www.wikidata.org/entity/Q18529684'), ('sName', 'David Davies'), ('p', 'http://www.wikidata.org/prop/direct/P1343'), ('pName', 'described by source'), ('o', 'http://www.wikidata.org/entity/Q17037575'), ('oName', 'Oxford Biography Index')]
# [('s', 'http://www.wikidata.org/entity/Q18530173'), ('sName', 'John Brown'), ('p', 'http://www.wikidata.org/prop/direct/P1343'), ('pName', 'described by source'), ('o', 'http://www.wikidata.org/entity/Q17037575'), ('oName', 'Oxford Biography Index')]
# [('s', 'http://www.wikidata.org/entity/Q18530181'), ('sName', 'John Wright Brown'), ('p', 'http://www.wikidata.org/prop/direct/P1343'), ('pName', 'described by source'), ('o', 'http://www.wikidata.org/entity/Q17037575'), ('oName', 'Oxford Biography Index')]
# [('s', 'http://www.wikidata.org/entity/Q18534214'), ('sName', 'John Taylor'), ('p', 'http://www.wikidata.org/prop/direct/P1343'), ('pName', 'described by source'), ('o', 'http://www.wikidata.org/entity/Q17037575'), ('oName', 'Oxford Biography Index')]
# [('s', 'http://www.wikidata.org/entity/Q18546621'), ('sName', 'John Roland Phillips'), ('p', 'http://www.wikidata.org/prop/direct/P1343'), ('pName', 'described by source'), ('o', 'http://www.wikidata.org/entity/Q17037575'), ('oName', 'Oxford Biography Index')]
# [('s', 'http://www.wikidata.org/entity/Q18546651'), ('sName', 'John Williams'), ('p', 'http://www.wikidata.org/prop/direct/P1343'), ('pName', 'described by source'), ('o', 'http://www.wikidata.org/entity/Q17037575'), ('oName', 'Oxford Biography Index')]
# [('s', 'http://www.wikidata.org/entity/Q18546656'), ('sName', 'John Bickerton Williams'), ('p', 'http://www.wikidata.org/prop/direct/P1343'), ('pName', 'described by source'), ('o', 'http://www.wikidata.org/entity/Q17037575'), ('oName', 'Oxford Biography Index')]
# [('s', 'http://www.wikidata.org/entity/Q7528143'), ('sName', 'Sir John Williams, 1st Baronet, of the City of London'), ('p', 'http://www.wikidata.org/prop/direct/P1343'), ('pName', 'described by source'), ('o', 'http://www.wikidata.org/entity/Q17037575'), ('oName', 'Oxford Biography Index')]
# [('s', 'http://www.wikidata.org/entity/Q18593621'), ('sName', 'William Moore'), ('p', 'http://www.wikidata.org/prop/direct/P1343'), ('pName', 'described by source'), ('o', 'http://www.wikidata.org/entity/Q17037575'), ('oName', 'Oxford Biography Index')]
# [('s', 'http://www.wikidata.org/entity/Q18729868'), ('sName', 'Entesa per Arbúcies'), ('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q13010'), ('oName', 'Arbúcies')]
# [('s', 'http://www.wikidata.org/entity/Q12475627'), ('sName', 'Belimbing, Melawi'), ('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q14162'), ('oName', 'Melawi')]
# [('s', 'http://www.wikidata.org/entity/Q8213273'), ('sName', 'Serasan'), ('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q10100'), ('oName', 'Natuna')]
# [('s', 'http://www.wikidata.org/entity/Q1905256'), ('sName', 'Martin Wikelski'), ('p', 'http://www.wikidata.org/prop/direct/P108'), ('pName', 'employer'), ('o', 'http://www.wikidata.org/entity/Q1673980'), ('oName', 'Smithsonian Tropical Research Institute')]
# [('s', 'http://www.wikidata.org/entity/Q21611757'), ('sName', 'Juan Carlos Villarreal Aguilar'), ('p', 'http://www.wikidata.org/prop/direct/P108'), ('pName', 'employer'), ('o', 'http://www.wikidata.org/entity/Q1673980'), ('oName', 'Smithsonian Tropical Research Institute')]
# [('s', 'http://www.wikidata.org/entity/Q24035454'), ('sName', 'el Vidal'), ('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q13010'), ('oName', 'Arbúcies')]
# [('s', 'http://www.wikidata.org/entity/Q57080337'), ('sName', 'David I Kline'), ('p', 'http://www.wikidata.org/prop/direct/P108'), ('pName', 'employer'), ('o', 'http://www.wikidata.org/entity/Q1673980'), ('oName', 'Smithsonian Tropical Research Institute')]
# [('s', 'http://www.wikidata.org/entity/Q44790072'), ('sName', 'Sean R. Connolly'), ('p', 'http://www.wikidata.org/prop/direct/P108'), ('pName', 'employer'), ('o', 'http://www.wikidata.org/entity/Q1673980'), ('oName', 'Smithsonian Tropical Research Institute')]
# [('s', 'http://www.wikidata.org/entity/Q60297756'), ('sName', 'Orpheus M Butler'), ('p', 'http://www.wikidata.org/prop/direct/P108'), ('pName', 'employer'), ('o', 'http://www.wikidata.org/entity/Q1673980'), ('oName', 'Smithsonian Tropical Research Institute')]
# [('s', 'http://www.wikidata.org/entity/Q19294986'), ('sName', 'Louis Berlioz'), ('p', 'http://www.wikidata.org/prop/direct/P101'), ('pName', 'field of work'), ('o', 'http://www.wikidata.org/entity/Q121713'), ('oName', 'acupuncture')]
# [('s', 'http://www.wikidata.org/entity/Q7980959'), ('sName', 'welfare fraud'), ('p', 'http://www.wikidata.org/prop/direct/P1269'), ('pName', 'facet of'), ('o', 'http://www.wikidata.org/entity/Q11497309'), ('oName', 'economic support')]
# [('s', 'http://www.wikidata.org/entity/Q7371387'), ('sName', 'Nagoya Expressway 16'), ('p', 'http://www.wikidata.org/prop/direct/P126'), ('pName', 'maintained by'), ('o', 'http://www.wikidata.org/entity/Q11415304'), ('oName', 'Nagoya Expressway Public Corporation')]
# [('s', 'http://www.wikidata.org/entity/Q80545'), ('sName', 'Oshiage Station'), ('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q11497641'), ('oName', 'Oshiage')]
# [('s', 'http://www.wikidata.org/entity/Q8191440'), ('sName', 'Nagoya Highway 11'), ('p', 'http://www.wikidata.org/prop/direct/P126'), ('pName', 'maintained by'), ('o', 'http://www.wikidata.org/entity/Q11415304'), ('oName', 'Nagoya Expressway Public Corporation')]
# [('s', 'http://www.wikidata.org/entity/Q8191440'), ('sName', 'Nagoya Highway 11'), ('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q1207964'), ('oName', 'Kita-ku')]
# [('s', 'http://www.wikidata.org/entity/Q8191440'), ('sName', 'Nagoya Highway 11'), ('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q1345562'), ('oName', 'Toyoyama')]
# [('s', 'http://www.wikidata.org/entity/Q4423406'), ('sName', 'Sliven Municipality'), ('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q113120'), ('oName', 'Sliven Province')]
# [('s', 'http://www.wikidata.org/entity/Q25563103'), ('sName', 'Warangal'), ('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q15399'), ('oName', 'Warangal District')]
# [('s', 'http://www.wikidata.org/entity/Q12383937'), ('sName', 'Augas Santas, Allariz'), ('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q1438879'), ('oName', 'Allariz')]
# [('s', 'http://www.wikidata.org/entity/Q2609479'), ('sName', 'Kotel Municipality'), ('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q113120'), ('oName', 'Sliven Province')]
# [('s', 'http://www.wikidata.org/entity/Q11494799'), ('sName', 'Aichi Prefectural Road Route 62'), ('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q1345562'), ('oName', 'Toyoyama')]
# [('s', 'http://www.wikidata.org/entity/Q12358779'), ('sName', 'Aleksandr Podkopajev'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('pName', 'occupation'), ('o', 'http://www.wikidata.org/entity/Q106823762'), ('oName', 'veterinary scientist')]
# [('s', 'http://www.wikidata.org/entity/Q12371070'), ('sName', 'Nikolai Prozorov'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('pName', 'occupation'), ('o', 'http://www.wikidata.org/entity/Q106823762'), ('oName', 'veterinary scientist')]
# [('s', 'http://www.wikidata.org/entity/Q12482400'), ('sName', 'Ella Hilir'), ('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q14162'), ('oName', 'Melawi')]
# [('s', 'http://www.wikidata.org/entity/Q8213279'), ('sName', 'Midai'), ('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q10100'), ('oName', 'Natuna')]
# 100

# %%
# Consider the tennis players born after 1975, return who won more Grand Slams and cut the result to the top-10 (the result set must be a list of triples player IRI, label and #victories).
# Q1426 = Roger Federer
# wdt:P1344 (participant in)
# wdt:P2522 (victory)
#[('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('o', 'http://www.wikidata.org/entity/P569'), ('oName', 'date of birth')]
# 1) getting winners dob 

queryString = """

SELECT DISTINCT ?s ?sName ?p ?pName ?o ?oName
WHERE {
   # ?s ?p ?o.
   # ?s sc:name ?sName.
   # ?p sc:name ?pName.
   # ?o sc:name ?oName.
   
   #it never returns the result if un-comment the filter
   #FILTER (REGEX(?pName,"[D|d][O|o][B|b]"))
}
LIMIT 10
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('s', 'http://www.wikidata.org/entity/Q95452024'), ('sName', 'Template:Vice Presidents of the Maldives'), ('p', 'http://www.wikidata.org/prop/direct/P1423'), ('pName', 'template has topic'), ('o', 'http://www.wikidata.org/entity/Q10999435'), ('oName', 'Vice President of the Maldives')]
# [('s', 'http://www.wikidata.org/entity/Q25752552'), ('sName', 'Template:2001 in Europe'), ('p', 'http://www.wikidata.org/prop/direct/P1423'), ('pName', 'template has topic'), ('o', 'http://www.wikidata.org/entity/Q17111750'), ('oName', '2001 in Europe')]
# [('s', 'http://www.wikidata.org/entity/Q6675314'), ('sName', 'Template:Alcest'), ('p', 'http://www.wikidata.org/prop/direct/P1423'), ('pName', 'template has topic'), ('o', 'http://www.wikidata.org/entity/Q1517060'), ('oName', 'Alcest')]
# [('s', 'http://www.wikidata.org/entity/Q22785857'), ('sName', 'Template:2006 in Europe'), ('p', 'http://www.wikidata.org/prop/direct/P1423'), ('pName', 'template has topic'), ('o', 'http://www.wikidata.org/entity/Q17111782'), ('oName', '2006 in Europe')]
# [('s', 'http://www.wikidata.org/entity/Q85816744'), ('sName', 'Yodli'), ('p', 'http://www.wikidata.org/prop/direct/P1268'), ('pName', 'represents'), ('o', 'http://www.wikidata.org/entity/Q1053559'), ('oName', '2020 Winter Youth Olympics')]
# [('s', 'http://www.wikidata.org/entity/Q1064606'), ('sName', 'President of the Maldives'), ('p', 'http://www.wikidata.org/prop/direct/P2098'), ('pName', 'substitute/deputy/replacement of office/officeholder'), ('o', 'http://www.wikidata.org/entity/Q10999435'), ('oName', 'Vice President of the Maldives')]
# [('s', 'http://www.wikidata.org/entity/Q10275776'), ('sName', 'Estação Ferroviária de Mafra'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q18483474'), ('sName', 'Telhada halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q8202323'), ('sName', 'Alcainça-Moinhos halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q8202353'), ('sName', 'Bicanho Halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# 10

# %%
# Consider the tennis players born after 1975, return who won more Grand Slams and cut the result to the top-10 (the result set must be a list of triples player IRI, label and #victories).
# Q1426 = Roger Federer
# wdt:P1344 (participant in)
# wdt:P2522 (victory)
#[('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('o', 'http://www.wikidata.org/entity/P569'), ('oName', 'date of birth')]
# 1) getting winners dob 

queryString = """

SELECT DISTINCT ?s ?sName ?p ?pName ?o ?oName
WHERE {
   # ?s ?p ?o.
   # ?s sc:name ?sName.
   # ?p sc:name ?pName.
   # ?o sc:name ?oName.
   
   # Sometime it returns the result and other it doesn't #comment the filter
   #FILTER (REGEX(?pName,"date.*"))
}
LIMIT 10
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('s', 'http://www.wikidata.org/entity/Q95452024'), ('sName', 'Template:Vice Presidents of the Maldives'), ('p', 'http://www.wikidata.org/prop/direct/P1423'), ('pName', 'template has topic'), ('o', 'http://www.wikidata.org/entity/Q10999435'), ('oName', 'Vice President of the Maldives')]
# [('s', 'http://www.wikidata.org/entity/Q25752552'), ('sName', 'Template:2001 in Europe'), ('p', 'http://www.wikidata.org/prop/direct/P1423'), ('pName', 'template has topic'), ('o', 'http://www.wikidata.org/entity/Q17111750'), ('oName', '2001 in Europe')]
# [('s', 'http://www.wikidata.org/entity/Q6675314'), ('sName', 'Template:Alcest'), ('p', 'http://www.wikidata.org/prop/direct/P1423'), ('pName', 'template has topic'), ('o', 'http://www.wikidata.org/entity/Q1517060'), ('oName', 'Alcest')]
# [('s', 'http://www.wikidata.org/entity/Q22785857'), ('sName', 'Template:2006 in Europe'), ('p', 'http://www.wikidata.org/prop/direct/P1423'), ('pName', 'template has topic'), ('o', 'http://www.wikidata.org/entity/Q17111782'), ('oName', '2006 in Europe')]
# [('s', 'http://www.wikidata.org/entity/Q85816744'), ('sName', 'Yodli'), ('p', 'http://www.wikidata.org/prop/direct/P1268'), ('pName', 'represents'), ('o', 'http://www.wikidata.org/entity/Q1053559'), ('oName', '2020 Winter Youth Olympics')]
# [('s', 'http://www.wikidata.org/entity/Q1064606'), ('sName', 'President of the Maldives'), ('p', 'http://www.wikidata.org/prop/direct/P2098'), ('pName', 'substitute/deputy/replacement of office/officeholder'), ('o', 'http://www.wikidata.org/entity/Q10999435'), ('oName', 'Vice President of the Maldives')]
# [('s', 'http://www.wikidata.org/entity/Q10275776'), ('sName', 'Estação Ferroviária de Mafra'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q18483474'), ('sName', 'Telhada halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q8202323'), ('sName', 'Alcainça-Moinhos halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q8202353'), ('sName', 'Bicanho Halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# 10

# %%
# Consider the tennis players born after 1975, return who won more Grand Slams and cut the result to the top-10 (the result set must be a list of triples player IRI, label and #victories).
# Q1426 = Roger Federer
# wdt:P1344 (participant in)
# wdt:P2522 (victory)
#[('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('o', 'http://www.wikidata.org/entity/P569'), ('oName', 'date of birth')]
# 1) getting winners dob 

queryString = """

SELECT DISTINCT ?s ?sName ?p ?pName ?o ?oName
WHERE {
   # ?s ?p ?o.
   # ?s sc:name ?sName.
   # ?p sc:name ?pName.
   # ?o sc:name ?oName.
   
   # sometimes filter with regex don't work
   #FILTER (REGEX(?pName,"date","i"))
   #FILTER (?p not in (wdt:P726, wdt:P991))
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('s', 'http://www.wikidata.org/entity/Q95452024'), ('sName', 'Template:Vice Presidents of the Maldives'), ('p', 'http://www.wikidata.org/prop/direct/P1423'), ('pName', 'template has topic'), ('o', 'http://www.wikidata.org/entity/Q10999435'), ('oName', 'Vice President of the Maldives')]
# [('s', 'http://www.wikidata.org/entity/Q25752552'), ('sName', 'Template:2001 in Europe'), ('p', 'http://www.wikidata.org/prop/direct/P1423'), ('pName', 'template has topic'), ('o', 'http://www.wikidata.org/entity/Q17111750'), ('oName', '2001 in Europe')]
# [('s', 'http://www.wikidata.org/entity/Q6675314'), ('sName', 'Template:Alcest'), ('p', 'http://www.wikidata.org/prop/direct/P1423'), ('pName', 'template has topic'), ('o', 'http://www.wikidata.org/entity/Q1517060'), ('oName', 'Alcest')]
# [('s', 'http://www.wikidata.org/entity/Q22785857'), ('sName', 'Template:2006 in Europe'), ('p', 'http://www.wikidata.org/prop/direct/P1423'), ('pName', 'template has topic'), ('o', 'http://www.wikidata.org/entity/Q17111782'), ('oName', '2006 in Europe')]
# [('s', 'http://www.wikidata.org/entity/Q85816744'), ('sName', 'Yodli'), ('p', 'http://www.wikidata.org/prop/direct/P1268'), ('pName', 'represents'), ('o', 'http://www.wikidata.org/entity/Q1053559'), ('oName', '2020 Winter Youth Olympics')]
# [('s', 'http://www.wikidata.org/entity/Q1064606'), ('sName', 'President of the Maldives'), ('p', 'http://www.wikidata.org/prop/direct/P2098'), ('pName', 'substitute/deputy/replacement of office/officeholder'), ('o', 'http://www.wikidata.org/entity/Q10999435'), ('oName', 'Vice President of the Maldives')]
# [('s', 'http://www.wikidata.org/entity/Q10275776'), ('sName', 'Estação Ferroviária de Mafra'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q18483474'), ('sName', 'Telhada halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q8202323'), ('sName', 'Alcainça-Moinhos halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q8202353'), ('sName', 'Bicanho Halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q8779275'), ('sName', 'Amieira train station'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q8841005'), ('sName', 'Malveira train station'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q17267254'), ('sName', 'Fanhais halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q17267315'), ('sName', 'Cela halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q8779401'), ('sName', 'Bombarral train station'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q8840924'), ('sName', 'Leiria train station'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q8841025'), ('sName', 'Marinha Grande station'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q8841035'), ('sName', 'Martingança train station'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q8841427'), ('sName', 'Pataias train station'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q8842140'), ('sName', 'Valado train station'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q248226'), ('sName', 'Agualva-Cacém railway station'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q18482873'), ('sName', 'Fontela halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q18482882'), ('sName', 'Fontela-A halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q18482941'), ('sName', 'Jerumelo halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q18483298'), ('sName', 'Salir do Porto halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q18483365'), ('sName', 'Sapataria Halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q800752'), ('sName', 'Figueira da Foz train station'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q8841452'), ('sName', 'Pero Negro train station'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q8841387'), ('sName', 'Outeiro train station'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q10275790'), ('sName', 'Sabugo train station'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q16781965'), ('sName', 'Pedra Furada halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q16781966'), ('sName', 'Telhal halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q17000336'), ('sName', 'Óbidos halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q587866'), ('sName', 'Estação Ferroviária de Caldas da Rainha'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q18482975'), ('sName', 'Lares halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q557982'), ('sName', 'Bifurcação de Lares train station'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q10275797'), ('sName', 'São Martinho do Porto train station'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q18482831'), ('sName', 'Famalicão da Nazaré halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q8841053'), ('sName', 'Mira Sintra-Meleças train station'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q10275778'), ('sName', 'Monte Real train station'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q18482642'), ('sName', 'Carriço halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q18482848'), ('sName', 'Feliteira halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q18482932'), ('sName', 'Guia halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q19702819'), ('sName', 'Monte Redondo halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q19702893'), ('sName', 'Zibreira halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q5552454'), ('sName', 'Dois Porto train station'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q8840980'), ('sName', 'Louriçal train station'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q18483271'), ('sName', 'Regueira de Pontes halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q8841573'), ('sName', 'Ramalhal train station'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q8842080'), ('sName', 'Torres Vedras train station'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q18483280'), ('sName', 'Ribeira de Seiça halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q19702853'), ('sName', 'Runa halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q18483456'), ('sName', 'São Mamede halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q38780585'), ('sName', 'First Minister of British Honduras'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q1643555'), ('oName', 'British Honduras')]
# [('s', 'http://www.wikidata.org/entity/Q26691790'), ('sName', 'mayor of Sant Pere Sallavinera'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q15967'), ('oName', 'Sant Pere Sallavinera')]
# [('s', 'http://www.wikidata.org/entity/Q105998262'), ('sName', 'Mayor of Star City'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q1419655'), ('oName', 'Star City')]
# [('s', 'http://www.wikidata.org/entity/Q108080825'), ('sName', 'Attorney-General of British Honduras'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q1643555'), ('oName', 'British Honduras')]
# [('s', 'http://www.wikidata.org/entity/Q26691184'), ('sName', 'mayor of Ripollet'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q13933'), ('oName', 'Ripollet')]
# [('s', 'http://www.wikidata.org/entity/Q56438477'), ('sName', 'mayor of Itano'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q1350904'), ('oName', 'Itano')]
# [('s', 'http://www.wikidata.org/entity/Q59773367'), ('sName', 'Arbúcies city councillor'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q13010'), ('oName', 'Arbúcies')]
# [('s', 'http://www.wikidata.org/entity/Q11907924'), ('sName', 'Flag of Ripollet'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q13933'), ('oName', 'Ripollet')]
# [('s', 'http://www.wikidata.org/entity/Q105514924'), ('sName', 'Ripollet results in 2021 Catalan parliamentary election'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q13933'), ('oName', 'Ripollet')]
# [('s', 'http://www.wikidata.org/entity/Q26695213'), ('sName', 'mayor of Pedreguer'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q1750923'), ('oName', 'Pedreguer')]
# [('s', 'http://www.wikidata.org/entity/Q44952776'), ('sName', 'Catalan regional election 2015 in Sant Pere Sallavinera'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q15967'), ('oName', 'Sant Pere Sallavinera')]
# [('s', 'http://www.wikidata.org/entity/Q101978391'), ('sName', 'Regional Regulation of Melawi Regency Number 04 Year 2018'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q14162'), ('oName', 'Melawi')]
# [('s', 'http://www.wikidata.org/entity/Q11481685'), ('sName', 'Hitachi Kokubunji'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q1055353'), ('oName', 'Hitachi Province')]
# [('s', 'http://www.wikidata.org/entity/Q26691392'), ('sName', 'mayor of Zalduendo de Álava'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q1443609'), ('oName', 'Zalduondo')]
# [('s', 'http://www.wikidata.org/entity/Q26695389'), ('sName', 'mayor of Cehegín'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q1757489'), ('oName', 'Cehegín')]
# [('s', 'http://www.wikidata.org/entity/Q62051046'), ('sName', 'Legislative Assembly of British Honduras'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q1643555'), ('oName', 'British Honduras')]
# [('s', 'http://www.wikidata.org/entity/Q26690765'), ('sName', 'mayor of Arbúcies'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q13010'), ('oName', 'Arbúcies')]
# [('s', 'http://www.wikidata.org/entity/Q105515175'), ('sName', 'Arbúcies results in 2021 Catalan parliamentary election'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q13010'), ('oName', 'Arbúcies')]
# [('s', 'http://www.wikidata.org/entity/Q44914898'), ('sName', 'Catalan regional election 2015 in Ripollet'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q13933'), ('oName', 'Ripollet')]
# [('s', 'http://www.wikidata.org/entity/Q45023173'), ('sName', 'Catalan regional election 2015 in Arbúcies'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q13010'), ('oName', 'Arbúcies')]
# [('s', 'http://www.wikidata.org/entity/Q56402053'), ('sName', 'Flag of Sant Pere Sallavinera'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q15967'), ('oName', 'Sant Pere Sallavinera')]
# [('s', 'http://www.wikidata.org/entity/Q56437866'), ('sName', 'mayor of Toyoyama'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q1345562'), ('oName', 'Toyoyama')]
# [('s', 'http://www.wikidata.org/entity/Q105514933'), ('sName', 'Sant Pere Sallavinera results in 2021 Catalan parliamentary election'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q15967'), ('oName', 'Sant Pere Sallavinera')]
# [('s', 'http://www.wikidata.org/entity/Q105482504'), ('sName', 'Arbúcies results in 2017 Catalan parliamentary election'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q13010'), ('oName', 'Arbúcies')]
# [('s', 'http://www.wikidata.org/entity/Q105482709'), ('sName', 'Ripollet results in 2017 Catalan parliamentary election'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q13933'), ('oName', 'Ripollet')]
# [('s', 'http://www.wikidata.org/entity/Q11481689'), ('sName', 'Hitachinokuni Sōshagū'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q1055353'), ('oName', 'Hitachi Province')]
# [('s', 'http://www.wikidata.org/entity/Q105481195'), ('sName', 'Sant Pere Sallavinera results in 2017 Catalan parliamentary election'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q15967'), ('oName', 'Sant Pere Sallavinera')]
# [('s', 'http://www.wikidata.org/entity/Q19294986'), ('sName', 'Louis Berlioz'), ('p', 'http://www.wikidata.org/prop/direct/P101'), ('pName', 'field of work'), ('o', 'http://www.wikidata.org/entity/Q121713'), ('oName', 'acupuncture')]
# [('s', 'http://www.wikidata.org/entity/Q64392269'), ('sName', 'Ian Gough'), ('p', 'http://www.wikidata.org/prop/direct/P101'), ('pName', 'field of work'), ('o', 'http://www.wikidata.org/entity/Q11497309'), ('oName', 'economic support')]
# [('s', 'http://www.wikidata.org/entity/Q19957642'), ('sName', 'Ruby Duncan'), ('p', 'http://www.wikidata.org/prop/direct/P101'), ('pName', 'field of work'), ('o', 'http://www.wikidata.org/entity/Q11497309'), ('oName', 'economic support')]
# [('s', 'http://www.wikidata.org/entity/Q81425306'), ('sName', 'Physiotherapy Douma'), ('p', 'http://www.wikidata.org/prop/direct/P101'), ('pName', 'field of work'), ('o', 'http://www.wikidata.org/entity/Q121713'), ('oName', 'acupuncture')]
# [('s', 'http://www.wikidata.org/entity/Q15809258'), ('sName', 'Healer of Berne'), ('p', 'http://www.wikidata.org/prop/direct/P101'), ('pName', 'field of work'), ('o', 'http://www.wikidata.org/entity/Q121713'), ('oName', 'acupuncture')]
# [('s', 'http://www.wikidata.org/entity/Q66535461'), ('sName', 'Emmanuel Kreike'), ('p', 'http://www.wikidata.org/prop/direct/P101'), ('pName', 'field of work'), ('o', 'http://www.wikidata.org/entity/Q11497309'), ('oName', 'economic support')]
# [('s', 'http://www.wikidata.org/entity/Q6066216'), ('sName', 'Ira Rubinoff'), ('p', 'http://www.wikidata.org/prop/direct/P101'), ('pName', 'field of work'), ('o', 'http://www.wikidata.org/entity/Q1673980'), ('oName', 'Smithsonian Tropical Research Institute')]
# [('s', 'http://www.wikidata.org/entity/Q55600270'), ('sName', 'Élise Boghossian'), ('p', 'http://www.wikidata.org/prop/direct/P101'), ('pName', 'field of work'), ('o', 'http://www.wikidata.org/entity/Q121713'), ('oName', 'acupuncture')]
# [('s', 'http://www.wikidata.org/entity/Q9044036'), ('sName', 'Su Yu-chang'), ('p', 'http://www.wikidata.org/prop/direct/P101'), ('pName', 'field of work'), ('o', 'http://www.wikidata.org/entity/Q121713'), ('oName', 'acupuncture')]
# [('s', 'http://www.wikidata.org/entity/Q17107163'), ('sName', 'Vilhelm Schjelderup'), ('p', 'http://www.wikidata.org/prop/direct/P101'), ('pName', 'field of work'), ('o', 'http://www.wikidata.org/entity/Q121713'), ('oName', 'acupuncture')]
# [('s', 'http://www.wikidata.org/entity/Q97147261'), ('sName', 'Clinics Dr. Erler'), ('p', 'http://www.wikidata.org/prop/direct/P101'), ('pName', 'field of work'), ('o', 'http://www.wikidata.org/entity/Q121713'), ('oName', 'acupuncture')]
# [('s', 'http://www.wikidata.org/entity/Q64175666'), ('sName', 'Jeremy Ross'), ('p', 'http://www.wikidata.org/prop/direct/P101'), ('pName', 'field of work'), ('o', 'http://www.wikidata.org/entity/Q121713'), ('oName', 'acupuncture')]
# [('s', 'http://www.wikidata.org/entity/Q96579961'), ('sName', 'Sana Clinic Nuremberg'), ('p', 'http://www.wikidata.org/prop/direct/P101'), ('pName', 'field of work'), ('o', 'http://www.wikidata.org/entity/Q121713'), ('oName', 'acupuncture')]
# [('s', 'http://www.wikidata.org/entity/Q47544113'), ('sName', 'Maesiah Thabane'), ('p', 'http://www.wikidata.org/prop/direct/P102'), ('pName', 'member of political party'), ('o', 'http://www.wikidata.org/entity/Q1346132'), ('oName', 'All Basotho Convention')]
# [('s', 'http://www.wikidata.org/entity/Q9092970'), ('sName', 'Vera Grabe'), ('p', 'http://www.wikidata.org/prop/direct/P102'), ('pName', 'member of political party'), ('o', 'http://www.wikidata.org/entity/Q1789014'), ('oName', '19th of April Movement')]
# [('s', 'http://www.wikidata.org/entity/Q5992796'), ('sName', 'Ignatius Shixwameni'), ('p', 'http://www.wikidata.org/prop/direct/P102'), ('pName', 'member of political party'), ('o', 'http://www.wikidata.org/entity/Q1129391'), ('oName', "All People's Party")]
# [('s', 'http://www.wikidata.org/entity/Q16194214'), ('sName', 'Mophato Monyake'), ('p', 'http://www.wikidata.org/prop/direct/P102'), ('pName', 'member of political party'), ('o', 'http://www.wikidata.org/entity/Q1346132'), ('oName', 'All Basotho Convention')]
# [('s', 'http://www.wikidata.org/entity/Q3660117'), ('sName', 'Carlos Pizarro Leongómez'), ('p', 'http://www.wikidata.org/prop/direct/P102'), ('pName', 'member of political party'), ('o', 'http://www.wikidata.org/entity/Q1789014'), ('oName', '19th of April Movement')]
# [('s', 'http://www.wikidata.org/entity/Q1567660'), ('sName', 'Hae Phoofolo'), ('p', 'http://www.wikidata.org/prop/direct/P102'), ('pName', 'member of political party'), ('o', 'http://www.wikidata.org/entity/Q1346132'), ('oName', 'All Basotho Convention')]
# [('s', 'http://www.wikidata.org/entity/Q4752142'), ('sName', 'Anatol Arhire'), ('p', 'http://www.wikidata.org/prop/direct/P102'), ('pName', 'member of political party'), ('o', 'http://www.wikidata.org/entity/Q1280031'), ('oName', 'Alliance for European Integration')]
# 100

# %%
# Consider the tennis players born after 1975, return who won more Grand Slams and cut the result to the top-10 (the result set must be a list of triples player IRI, label and #victories).
# Q1426 = Roger Federer
# wdt:P1344 (participant in)
# wdt:P2522 (victory)
#[('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('o', 'http://www.wikidata.org/entity/P569'), ('oName', 'date of birth')]
# 1) getting winners dob 

queryString = """

SELECT DISTINCT ?p ?pName ?o ?oName
WHERE {
   wd:Q1426 ?p ?o.
   # ?p sc:name ?pName.
   # ?o sc:name ?oName.
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P2522'), ('pName', 'victory'), ('o', 'http://www.wikidata.org/entity/Q22956224'), ('oName', "2017 Australian Open – Men's Singles")]
# [('p', 'http://www.wikidata.org/prop/direct/P2522'), ('pName', 'victory'), ('o', 'http://www.wikidata.org/entity/Q612597'), ('oName', '2007 Tennis Masters Cup')]
# [('p', 'http://www.wikidata.org/prop/direct/P3342'), ('pName', 'significant person'), ('o', 'http://www.wikidata.org/entity/Q54584'), ('oName', 'Andy Roddick')]
# [('p', 'http://www.wikidata.org/prop/direct/P166'), ('pName', 'award received'), ('o', 'http://www.wikidata.org/entity/Q56509472'), ('oName', 'honorary doctor of the University of Basel')]
# [('p', 'http://www.wikidata.org/prop/direct/P1344'), ('pName', 'participant in'), ('o', 'http://www.wikidata.org/entity/Q589310'), ('oName', "tennis at the 2000 Summer Olympics – men's singles")]
# [('p', 'http://www.wikidata.org/prop/direct/P6758'), ('pName', 'supported sports team'), ('o', 'http://www.wikidata.org/entity/Q189671'), ('oName', 'FC Basel')]
# [('p', 'http://www.wikidata.org/prop/direct/P2522'), ('pName', 'victory'), ('o', 'http://www.wikidata.org/entity/Q782589'), ('oName', "2010 Australian Open – Men's Singles")]
# [('p', 'http://www.wikidata.org/prop/direct/P2522'), ('pName', 'victory'), ('o', 'http://www.wikidata.org/entity/Q782420'), ('oName', "2006 Australian Open – Men's Singles")]
# [('p', 'http://www.wikidata.org/prop/direct/P166'), ('pName', 'award received'), ('o', 'http://www.wikidata.org/entity/Q1061233'), ('oName', "L'Équipe Champion of Champions")]
# [('p', 'http://www.wikidata.org/prop/direct/P106'), ('pName', 'occupation'), ('o', 'http://www.wikidata.org/entity/Q10833314'), ('oName', 'tennis player')]
# [('p', 'http://www.wikidata.org/prop/direct/P741'), ('pName', 'playing hand'), ('o', 'http://www.wikidata.org/entity/Q14420039'), ('oName', 'one-handed backhand')]
# [('p', 'http://www.wikidata.org/prop/direct/P1412'), ('pName', 'languages spoken, written or signed'), ('o', 'http://www.wikidata.org/entity/Q150'), ('oName', 'French')]
# [('p', 'http://www.wikidata.org/prop/direct/P1343'), ('pName', 'described by source'), ('o', 'http://www.wikidata.org/entity/Q17290934'), ('oName', 'Lentapedia')]
# [('p', 'http://www.wikidata.org/prop/direct/P1412'), ('pName', 'languages spoken, written or signed'), ('o', 'http://www.wikidata.org/entity/Q1860'), ('oName', 'English')]
# [('p', 'http://www.wikidata.org/prop/direct/P103'), ('pName', 'native language'), ('o', 'http://www.wikidata.org/entity/Q188'), ('oName', 'German')]
# [('p', 'http://www.wikidata.org/prop/direct/P1412'), ('pName', 'languages spoken, written or signed'), ('o', 'http://www.wikidata.org/entity/Q188'), ('oName', 'German')]
# [('p', 'http://www.wikidata.org/prop/direct/P39'), ('pName', 'position held'), ('o', 'http://www.wikidata.org/entity/Q19969187'), ('oName', 'UNICEF Goodwill Ambassador')]
# [('p', 'http://www.wikidata.org/prop/direct/P552'), ('pName', 'handedness'), ('o', 'http://www.wikidata.org/entity/Q3039938'), ('oName', 'right-handedness')]
# [('p', 'http://www.wikidata.org/prop/direct/P1532'), ('pName', 'country for sport'), ('o', 'http://www.wikidata.org/entity/Q39'), ('oName', 'Switzerland')]
# [('p', 'http://www.wikidata.org/prop/direct/P27'), ('pName', 'country of citizenship'), ('o', 'http://www.wikidata.org/entity/Q39'), ('oName', 'Switzerland')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('o', 'http://www.wikidata.org/entity/Q5'), ('oName', 'human')]
# [('p', 'http://www.wikidata.org/prop/direct/P21'), ('pName', 'sex or gender'), ('o', 'http://www.wikidata.org/entity/Q6581097'), ('oName', 'male')]
# [('p', 'http://www.wikidata.org/prop/direct/P1343'), ('pName', 'described by source'), ('o', 'http://www.wikidata.org/entity/Q67311526'), ('oName', 'Obalky knih.cz')]
# [('p', 'http://www.wikidata.org/prop/direct/P108'), ('pName', 'employer'), ('o', 'http://www.wikidata.org/entity/Q740308'), ('oName', 'UNICEF')]
# [('p', 'http://www.wikidata.org/prop/direct/P19'), ('pName', 'place of birth'), ('o', 'http://www.wikidata.org/entity/Q78'), ('oName', 'Basel')]
# [('p', 'http://www.wikidata.org/prop/direct/P641'), ('pName', 'sport'), ('o', 'http://www.wikidata.org/entity/Q847'), ('oName', 'tennis')]
# [('p', 'http://www.wikidata.org/prop/direct/P1344'), ('pName', 'participant in'), ('o', 'http://www.wikidata.org/entity/Q8544'), ('oName', '2000 Summer Olympics')]
# [('p', 'http://www.wikidata.org/prop/direct/P1344'), ('pName', 'participant in'), ('o', 'http://www.wikidata.org/entity/Q8558'), ('oName', '2004 Summer Olympics')]
# [('p', 'http://www.wikidata.org/prop/direct/P140'), ('pName', 'religion'), ('o', 'http://www.wikidata.org/entity/Q9592'), ('oName', 'Catholic Church')]
# [('p', 'http://www.wikidata.org/prop/direct/P2522'), ('pName', 'victory'), ('o', 'http://www.wikidata.org/entity/Q300024'), ('oName', '2011 ATP World Tour Finals')]
# [('p', 'http://www.wikidata.org/prop/direct/P2416'), ('pName', 'sports discipline competed in'), ('o', 'http://www.wikidata.org/entity/Q18123880'), ('oName', 'tennis singles')]
# [('p', 'http://www.wikidata.org/prop/direct/P2416'), ('pName', 'sports discipline competed in'), ('o', 'http://www.wikidata.org/entity/Q18123885'), ('oName', 'tennis doubles')]
# [('p', 'http://www.wikidata.org/prop/direct/P735'), ('pName', 'given name'), ('o', 'http://www.wikidata.org/entity/Q4925304'), ('oName', 'Roger')]
# [('p', 'http://www.wikidata.org/prop/direct/P166'), ('pName', 'award received'), ('o', 'http://www.wikidata.org/entity/Q338737'), ('oName', 'Swiss Sports Personality of the Year')]
# [('p', 'http://www.wikidata.org/prop/direct/P166'), ('pName', 'award received'), ('o', 'http://www.wikidata.org/entity/Q3494048'), ('oName', 'BBC Overseas Sports Personality of the Year')]
# [('p', 'http://www.wikidata.org/prop/direct/P1344'), ('pName', 'participant in'), ('o', 'http://www.wikidata.org/entity/Q581788'), ('oName', "tennis at the 2012 Summer Olympics – men's singles")]
# [('p', 'http://www.wikidata.org/prop/direct/P2522'), ('pName', 'victory'), ('o', 'http://www.wikidata.org/entity/Q753300'), ('oName', "2012 Wimbledon Championships – Gentlemen's Singles")]
# [('p', 'http://www.wikidata.org/prop/direct/P1344'), ('pName', 'participant in'), ('o', 'http://www.wikidata.org/entity/Q757054'), ('oName', "tennis at the 2008 Summer Olympics – men's doubles")]
# [('p', 'http://www.wikidata.org/prop/direct/P2522'), ('pName', 'victory'), ('o', 'http://www.wikidata.org/entity/Q757054'), ('oName', "tennis at the 2008 Summer Olympics – men's doubles")]
# [('p', 'http://www.wikidata.org/prop/direct/P2522'), ('pName', 'victory'), ('o', 'http://www.wikidata.org/entity/Q1074654'), ('oName', "2006 Wimbledon Championships – Men's Singles")]
# [('p', 'http://www.wikidata.org/prop/direct/P2522'), ('pName', 'victory'), ('o', 'http://www.wikidata.org/entity/Q384929'), ('oName', "2005 Wimbledon Championships – Men's Singles")]
# [('p', 'http://www.wikidata.org/prop/direct/P551'), ('pName', 'residence'), ('o', 'http://www.wikidata.org/entity/Q70036'), ('oName', 'Bottmingen')]
# [('p', 'http://www.wikidata.org/prop/direct/P2522'), ('pName', 'victory'), ('o', 'http://www.wikidata.org/entity/Q14916861'), ('oName', '2014 Davis Cup')]
# [('p', 'http://www.wikidata.org/prop/direct/P741'), ('pName', 'playing hand'), ('o', 'http://www.wikidata.org/entity/Q14419931'), ('oName', 'one-handed forehand')]
# [('p', 'http://www.wikidata.org/prop/direct/P2522'), ('pName', 'victory'), ('o', 'http://www.wikidata.org/entity/Q46993124'), ('oName', "2018 Australian Open – Men's Singles")]
# [('p', 'http://www.wikidata.org/prop/direct/P166'), ('pName', 'award received'), ('o', 'http://www.wikidata.org/entity/Q4896696'), ('oName', 'Best International Athlete ESPY Award')]
# [('p', 'http://www.wikidata.org/prop/direct/P286'), ('pName', 'head coach'), ('o', 'http://www.wikidata.org/entity/Q15649219'), ('oName', 'Severin Lüthi')]
# [('p', 'http://www.wikidata.org/prop/direct/P734'), ('pName', 'family name'), ('o', 'http://www.wikidata.org/entity/Q16869916'), ('oName', 'Federer')]
# [('p', 'http://www.wikidata.org/prop/direct/P286'), ('pName', 'head coach'), ('o', 'http://www.wikidata.org/entity/Q261095'), ('oName', 'Ivan Ljubičić')]
# [('p', 'http://www.wikidata.org/prop/direct/P2522'), ('pName', 'victory'), ('o', 'http://www.wikidata.org/entity/Q964291'), ('oName', '2006 Tennis Masters Cup')]
# [('p', 'http://www.wikidata.org/prop/direct/P2522'), ('pName', 'victory'), ('o', 'http://www.wikidata.org/entity/Q300022'), ('oName', '2010 ATP World Tour Finals')]
# [('p', 'http://www.wikidata.org/prop/direct/P2522'), ('pName', 'victory'), ('o', 'http://www.wikidata.org/entity/Q1048953'), ('oName', "2004 US Open – Men's Singles")]
# [('p', 'http://www.wikidata.org/prop/direct/P2522'), ('pName', 'victory'), ('o', 'http://www.wikidata.org/entity/Q731509'), ('oName', "2005 US Open – Men's Singles")]
# [('p', 'http://www.wikidata.org/prop/direct/P2522'), ('pName', 'victory'), ('o', 'http://www.wikidata.org/entity/Q741573'), ('oName', "2009 French Open – Men's Singles")]
# [('p', 'http://www.wikidata.org/prop/direct/P2522'), ('pName', 'victory'), ('o', 'http://www.wikidata.org/entity/Q912506'), ('oName', "2006 US Open – Men's Singles")]
# [('p', 'http://www.wikidata.org/prop/direct/P2522'), ('pName', 'victory'), ('o', 'http://www.wikidata.org/entity/Q248965'), ('oName', "2004 Wimbledon Championships – Men's Singles")]
# [('p', 'http://www.wikidata.org/prop/direct/P2522'), ('pName', 'victory'), ('o', 'http://www.wikidata.org/entity/Q378627'), ('oName', "2003 Wimbledon Championships – Men's Singles")]
# [('p', 'http://www.wikidata.org/prop/direct/P286'), ('pName', 'head coach'), ('o', 'http://www.wikidata.org/entity/Q1348847'), ('oName', 'José Higueras')]
# [('p', 'http://www.wikidata.org/prop/direct/P2522'), ('pName', 'victory'), ('o', 'http://www.wikidata.org/entity/Q779654'), ('oName', "2004 Australian Open - men's singles")]
# [('p', 'http://www.wikidata.org/prop/direct/P2522'), ('pName', 'victory'), ('o', 'http://www.wikidata.org/entity/Q25344123'), ('oName', "2017 Wimbledon Championships – Men's Singles")]
# [('p', 'http://www.wikidata.org/prop/direct/P22'), ('pName', 'father'), ('o', 'http://www.wikidata.org/entity/Q17291275'), ('oName', 'Robert Federer')]
# [('p', 'http://www.wikidata.org/prop/direct/P25'), ('pName', 'mother'), ('o', 'http://www.wikidata.org/entity/Q17291278'), ('oName', 'Lynette Federer')]
# [('p', 'http://www.wikidata.org/prop/direct/P3373'), ('pName', 'sibling'), ('o', 'http://www.wikidata.org/entity/Q17291284'), ('oName', 'Dziana Federer')]
# [('p', 'http://www.wikidata.org/prop/direct/P40'), ('pName', 'child'), ('o', 'http://www.wikidata.org/entity/Q17291294'), ('oName', 'Myla Federer')]
# [('p', 'http://www.wikidata.org/prop/direct/P40'), ('pName', 'child'), ('o', 'http://www.wikidata.org/entity/Q17291300'), ('oName', 'Charlene Federer')]
# [('p', 'http://www.wikidata.org/prop/direct/P40'), ('pName', 'child'), ('o', 'http://www.wikidata.org/entity/Q17291308'), ('oName', 'Leo Federer')]
# [('p', 'http://www.wikidata.org/prop/direct/P40'), ('pName', 'child'), ('o', 'http://www.wikidata.org/entity/Q17291316'), ('oName', 'Lennart Federer')]
# [('p', 'http://www.wikidata.org/prop/direct/P26'), ('pName', 'spouse'), ('o', 'http://www.wikidata.org/entity/Q233306'), ('oName', 'Mirka Federer')]
# [('p', 'http://www.wikidata.org/prop/direct/P2522'), ('pName', 'victory'), ('o', 'http://www.wikidata.org/entity/Q2478340'), ('oName', '2011 BNP Paribas Masters – singles')]
# [('p', 'http://www.wikidata.org/prop/direct/P2522'), ('pName', 'victory'), ('o', 'http://www.wikidata.org/entity/Q751798'), ('oName', "2009 Wimbledon Championships – Men's Singles")]
# [('p', 'http://www.wikidata.org/prop/direct/P166'), ('pName', 'award received'), ('o', 'http://www.wikidata.org/entity/Q693708'), ('oName', 'ITF World Champions')]
# [('p', 'http://www.wikidata.org/prop/direct/P2522'), ('pName', 'victory'), ('o', 'http://www.wikidata.org/entity/Q782451'), ('oName', "2007 Australian Open – Men's Singles")]
# [('p', 'http://www.wikidata.org/prop/direct/P2522'), ('pName', 'victory'), ('o', 'http://www.wikidata.org/entity/Q912483'), ('oName', "2007 Wimbledon Championships – Men's Singles")]
# [('p', 'http://www.wikidata.org/prop/direct/P2522'), ('pName', 'victory'), ('o', 'http://www.wikidata.org/entity/Q304072'), ('oName', "2008 US Open – Men's Singles")]
# [('p', 'http://www.wikidata.org/prop/direct/P2522'), ('pName', 'victory'), ('o', 'http://www.wikidata.org/entity/Q2031910'), ('oName', '2003 Tennis Masters Cup')]
# [('p', 'http://www.wikidata.org/prop/direct/P2522'), ('pName', 'victory'), ('o', 'http://www.wikidata.org/entity/Q2094307'), ('oName', '2004 Tennis Masters Cup')]
# [('p', 'http://www.wikidata.org/prop/direct/P2522'), ('pName', 'victory'), ('o', 'http://www.wikidata.org/entity/Q836815'), ('oName', "2007 US Open – Men's Singles")]
# [('p', 'http://www.wikidata.org/prop/direct/P910'), ('pName', "topic's main category"), ('o', 'http://www.wikidata.org/entity/Q7257144'), ('oName', 'Category:Roger Federer')]
# [('p', 'http://www.wikidata.org/prop/direct/P286'), ('pName', 'head coach'), ('o', 'http://www.wikidata.org/entity/Q1968483'), ('oName', 'Peter Carter')]
# [('p', 'http://www.wikidata.org/prop/direct/P463'), ('pName', 'member of'), ('o', 'http://www.wikidata.org/entity/Q1675504'), ('oName', 'Swiss Tennis')]
# 80

# %%
# Consider the tennis players born after 1975, return who won more Grand Slams and cut the result to the top-10 (the result set must be a list of triples player IRI, label and #victories).
# Q1426 = Roger Federer
# wdt:P1344 (participant in)
# wdt:P2522 (victory)
#[('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('o', 'http://www.wikidata.org/entity/P569'), ('oName', 'date of birth')]
# 1) getting winners dob 

queryString = """

SELECT DISTINCT ?s ?sName ?p ?pName ?o ?oName
WHERE {
   # ?s ?p ?o.
   # ?s sc:name ?sName.
   # ?p sc:name ?pName.
   # ?o sc:name ?oName.
   
   #this time filter doesnt work 
   #FILTER (REGEX(?pName,"year","i"))
   #FILTER (?p not in (wdt:P726, wdt:P991))
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('s', 'http://www.wikidata.org/entity/Q95452024'), ('sName', 'Template:Vice Presidents of the Maldives'), ('p', 'http://www.wikidata.org/prop/direct/P1423'), ('pName', 'template has topic'), ('o', 'http://www.wikidata.org/entity/Q10999435'), ('oName', 'Vice President of the Maldives')]
# [('s', 'http://www.wikidata.org/entity/Q25752552'), ('sName', 'Template:2001 in Europe'), ('p', 'http://www.wikidata.org/prop/direct/P1423'), ('pName', 'template has topic'), ('o', 'http://www.wikidata.org/entity/Q17111750'), ('oName', '2001 in Europe')]
# [('s', 'http://www.wikidata.org/entity/Q6675314'), ('sName', 'Template:Alcest'), ('p', 'http://www.wikidata.org/prop/direct/P1423'), ('pName', 'template has topic'), ('o', 'http://www.wikidata.org/entity/Q1517060'), ('oName', 'Alcest')]
# [('s', 'http://www.wikidata.org/entity/Q22785857'), ('sName', 'Template:2006 in Europe'), ('p', 'http://www.wikidata.org/prop/direct/P1423'), ('pName', 'template has topic'), ('o', 'http://www.wikidata.org/entity/Q17111782'), ('oName', '2006 in Europe')]
# [('s', 'http://www.wikidata.org/entity/Q85816744'), ('sName', 'Yodli'), ('p', 'http://www.wikidata.org/prop/direct/P1268'), ('pName', 'represents'), ('o', 'http://www.wikidata.org/entity/Q1053559'), ('oName', '2020 Winter Youth Olympics')]
# [('s', 'http://www.wikidata.org/entity/Q1064606'), ('sName', 'President of the Maldives'), ('p', 'http://www.wikidata.org/prop/direct/P2098'), ('pName', 'substitute/deputy/replacement of office/officeholder'), ('o', 'http://www.wikidata.org/entity/Q10999435'), ('oName', 'Vice President of the Maldives')]
# [('s', 'http://www.wikidata.org/entity/Q10275776'), ('sName', 'Estação Ferroviária de Mafra'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q18483474'), ('sName', 'Telhada halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q8202323'), ('sName', 'Alcainça-Moinhos halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q8202353'), ('sName', 'Bicanho Halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q8779275'), ('sName', 'Amieira train station'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q8841005'), ('sName', 'Malveira train station'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q17267254'), ('sName', 'Fanhais halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q17267315'), ('sName', 'Cela halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q8779401'), ('sName', 'Bombarral train station'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q8840924'), ('sName', 'Leiria train station'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q8841025'), ('sName', 'Marinha Grande station'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q8841035'), ('sName', 'Martingança train station'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q8841427'), ('sName', 'Pataias train station'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q8842140'), ('sName', 'Valado train station'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q248226'), ('sName', 'Agualva-Cacém railway station'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q18482873'), ('sName', 'Fontela halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q18482882'), ('sName', 'Fontela-A halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q18482941'), ('sName', 'Jerumelo halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q18483298'), ('sName', 'Salir do Porto halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q18483365'), ('sName', 'Sapataria Halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q800752'), ('sName', 'Figueira da Foz train station'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q8841452'), ('sName', 'Pero Negro train station'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q8841387'), ('sName', 'Outeiro train station'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q10275790'), ('sName', 'Sabugo train station'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q16781965'), ('sName', 'Pedra Furada halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q16781966'), ('sName', 'Telhal halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q17000336'), ('sName', 'Óbidos halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q587866'), ('sName', 'Estação Ferroviária de Caldas da Rainha'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q18482975'), ('sName', 'Lares halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q557982'), ('sName', 'Bifurcação de Lares train station'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q10275797'), ('sName', 'São Martinho do Porto train station'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q18482831'), ('sName', 'Famalicão da Nazaré halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q8841053'), ('sName', 'Mira Sintra-Meleças train station'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q10275778'), ('sName', 'Monte Real train station'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q18482642'), ('sName', 'Carriço halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q18482848'), ('sName', 'Feliteira halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q18482932'), ('sName', 'Guia halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q19702819'), ('sName', 'Monte Redondo halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q19702893'), ('sName', 'Zibreira halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q5552454'), ('sName', 'Dois Porto train station'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q8840980'), ('sName', 'Louriçal train station'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q18483271'), ('sName', 'Regueira de Pontes halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q8841573'), ('sName', 'Ramalhal train station'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q8842080'), ('sName', 'Torres Vedras train station'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q18483280'), ('sName', 'Ribeira de Seiça halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q19702853'), ('sName', 'Runa halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q18483456'), ('sName', 'São Mamede halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q38780585'), ('sName', 'First Minister of British Honduras'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q1643555'), ('oName', 'British Honduras')]
# [('s', 'http://www.wikidata.org/entity/Q26691790'), ('sName', 'mayor of Sant Pere Sallavinera'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q15967'), ('oName', 'Sant Pere Sallavinera')]
# [('s', 'http://www.wikidata.org/entity/Q105998262'), ('sName', 'Mayor of Star City'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q1419655'), ('oName', 'Star City')]
# [('s', 'http://www.wikidata.org/entity/Q108080825'), ('sName', 'Attorney-General of British Honduras'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q1643555'), ('oName', 'British Honduras')]
# [('s', 'http://www.wikidata.org/entity/Q26691184'), ('sName', 'mayor of Ripollet'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q13933'), ('oName', 'Ripollet')]
# [('s', 'http://www.wikidata.org/entity/Q56438477'), ('sName', 'mayor of Itano'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q1350904'), ('oName', 'Itano')]
# [('s', 'http://www.wikidata.org/entity/Q59773367'), ('sName', 'Arbúcies city councillor'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q13010'), ('oName', 'Arbúcies')]
# [('s', 'http://www.wikidata.org/entity/Q11907924'), ('sName', 'Flag of Ripollet'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q13933'), ('oName', 'Ripollet')]
# [('s', 'http://www.wikidata.org/entity/Q105514924'), ('sName', 'Ripollet results in 2021 Catalan parliamentary election'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q13933'), ('oName', 'Ripollet')]
# [('s', 'http://www.wikidata.org/entity/Q26695213'), ('sName', 'mayor of Pedreguer'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q1750923'), ('oName', 'Pedreguer')]
# [('s', 'http://www.wikidata.org/entity/Q44952776'), ('sName', 'Catalan regional election 2015 in Sant Pere Sallavinera'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q15967'), ('oName', 'Sant Pere Sallavinera')]
# [('s', 'http://www.wikidata.org/entity/Q101978391'), ('sName', 'Regional Regulation of Melawi Regency Number 04 Year 2018'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q14162'), ('oName', 'Melawi')]
# [('s', 'http://www.wikidata.org/entity/Q11481685'), ('sName', 'Hitachi Kokubunji'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q1055353'), ('oName', 'Hitachi Province')]
# [('s', 'http://www.wikidata.org/entity/Q26691392'), ('sName', 'mayor of Zalduendo de Álava'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q1443609'), ('oName', 'Zalduondo')]
# [('s', 'http://www.wikidata.org/entity/Q26695389'), ('sName', 'mayor of Cehegín'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q1757489'), ('oName', 'Cehegín')]
# [('s', 'http://www.wikidata.org/entity/Q62051046'), ('sName', 'Legislative Assembly of British Honduras'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q1643555'), ('oName', 'British Honduras')]
# [('s', 'http://www.wikidata.org/entity/Q26690765'), ('sName', 'mayor of Arbúcies'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q13010'), ('oName', 'Arbúcies')]
# [('s', 'http://www.wikidata.org/entity/Q105515175'), ('sName', 'Arbúcies results in 2021 Catalan parliamentary election'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q13010'), ('oName', 'Arbúcies')]
# [('s', 'http://www.wikidata.org/entity/Q44914898'), ('sName', 'Catalan regional election 2015 in Ripollet'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q13933'), ('oName', 'Ripollet')]
# [('s', 'http://www.wikidata.org/entity/Q45023173'), ('sName', 'Catalan regional election 2015 in Arbúcies'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q13010'), ('oName', 'Arbúcies')]
# [('s', 'http://www.wikidata.org/entity/Q56402053'), ('sName', 'Flag of Sant Pere Sallavinera'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q15967'), ('oName', 'Sant Pere Sallavinera')]
# [('s', 'http://www.wikidata.org/entity/Q56437866'), ('sName', 'mayor of Toyoyama'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q1345562'), ('oName', 'Toyoyama')]
# [('s', 'http://www.wikidata.org/entity/Q105514933'), ('sName', 'Sant Pere Sallavinera results in 2021 Catalan parliamentary election'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q15967'), ('oName', 'Sant Pere Sallavinera')]
# [('s', 'http://www.wikidata.org/entity/Q105482504'), ('sName', 'Arbúcies results in 2017 Catalan parliamentary election'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q13010'), ('oName', 'Arbúcies')]
# [('s', 'http://www.wikidata.org/entity/Q105482709'), ('sName', 'Ripollet results in 2017 Catalan parliamentary election'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q13933'), ('oName', 'Ripollet')]
# [('s', 'http://www.wikidata.org/entity/Q11481689'), ('sName', 'Hitachinokuni Sōshagū'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q1055353'), ('oName', 'Hitachi Province')]
# [('s', 'http://www.wikidata.org/entity/Q105481195'), ('sName', 'Sant Pere Sallavinera results in 2017 Catalan parliamentary election'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q15967'), ('oName', 'Sant Pere Sallavinera')]
# [('s', 'http://www.wikidata.org/entity/Q19294986'), ('sName', 'Louis Berlioz'), ('p', 'http://www.wikidata.org/prop/direct/P101'), ('pName', 'field of work'), ('o', 'http://www.wikidata.org/entity/Q121713'), ('oName', 'acupuncture')]
# [('s', 'http://www.wikidata.org/entity/Q64392269'), ('sName', 'Ian Gough'), ('p', 'http://www.wikidata.org/prop/direct/P101'), ('pName', 'field of work'), ('o', 'http://www.wikidata.org/entity/Q11497309'), ('oName', 'economic support')]
# [('s', 'http://www.wikidata.org/entity/Q19957642'), ('sName', 'Ruby Duncan'), ('p', 'http://www.wikidata.org/prop/direct/P101'), ('pName', 'field of work'), ('o', 'http://www.wikidata.org/entity/Q11497309'), ('oName', 'economic support')]
# [('s', 'http://www.wikidata.org/entity/Q81425306'), ('sName', 'Physiotherapy Douma'), ('p', 'http://www.wikidata.org/prop/direct/P101'), ('pName', 'field of work'), ('o', 'http://www.wikidata.org/entity/Q121713'), ('oName', 'acupuncture')]
# [('s', 'http://www.wikidata.org/entity/Q15809258'), ('sName', 'Healer of Berne'), ('p', 'http://www.wikidata.org/prop/direct/P101'), ('pName', 'field of work'), ('o', 'http://www.wikidata.org/entity/Q121713'), ('oName', 'acupuncture')]
# [('s', 'http://www.wikidata.org/entity/Q66535461'), ('sName', 'Emmanuel Kreike'), ('p', 'http://www.wikidata.org/prop/direct/P101'), ('pName', 'field of work'), ('o', 'http://www.wikidata.org/entity/Q11497309'), ('oName', 'economic support')]
# [('s', 'http://www.wikidata.org/entity/Q6066216'), ('sName', 'Ira Rubinoff'), ('p', 'http://www.wikidata.org/prop/direct/P101'), ('pName', 'field of work'), ('o', 'http://www.wikidata.org/entity/Q1673980'), ('oName', 'Smithsonian Tropical Research Institute')]
# [('s', 'http://www.wikidata.org/entity/Q55600270'), ('sName', 'Élise Boghossian'), ('p', 'http://www.wikidata.org/prop/direct/P101'), ('pName', 'field of work'), ('o', 'http://www.wikidata.org/entity/Q121713'), ('oName', 'acupuncture')]
# [('s', 'http://www.wikidata.org/entity/Q9044036'), ('sName', 'Su Yu-chang'), ('p', 'http://www.wikidata.org/prop/direct/P101'), ('pName', 'field of work'), ('o', 'http://www.wikidata.org/entity/Q121713'), ('oName', 'acupuncture')]
# [('s', 'http://www.wikidata.org/entity/Q17107163'), ('sName', 'Vilhelm Schjelderup'), ('p', 'http://www.wikidata.org/prop/direct/P101'), ('pName', 'field of work'), ('o', 'http://www.wikidata.org/entity/Q121713'), ('oName', 'acupuncture')]
# [('s', 'http://www.wikidata.org/entity/Q97147261'), ('sName', 'Clinics Dr. Erler'), ('p', 'http://www.wikidata.org/prop/direct/P101'), ('pName', 'field of work'), ('o', 'http://www.wikidata.org/entity/Q121713'), ('oName', 'acupuncture')]
# [('s', 'http://www.wikidata.org/entity/Q64175666'), ('sName', 'Jeremy Ross'), ('p', 'http://www.wikidata.org/prop/direct/P101'), ('pName', 'field of work'), ('o', 'http://www.wikidata.org/entity/Q121713'), ('oName', 'acupuncture')]
# [('s', 'http://www.wikidata.org/entity/Q96579961'), ('sName', 'Sana Clinic Nuremberg'), ('p', 'http://www.wikidata.org/prop/direct/P101'), ('pName', 'field of work'), ('o', 'http://www.wikidata.org/entity/Q121713'), ('oName', 'acupuncture')]
# [('s', 'http://www.wikidata.org/entity/Q47544113'), ('sName', 'Maesiah Thabane'), ('p', 'http://www.wikidata.org/prop/direct/P102'), ('pName', 'member of political party'), ('o', 'http://www.wikidata.org/entity/Q1346132'), ('oName', 'All Basotho Convention')]
# [('s', 'http://www.wikidata.org/entity/Q9092970'), ('sName', 'Vera Grabe'), ('p', 'http://www.wikidata.org/prop/direct/P102'), ('pName', 'member of political party'), ('o', 'http://www.wikidata.org/entity/Q1789014'), ('oName', '19th of April Movement')]
# [('s', 'http://www.wikidata.org/entity/Q5992796'), ('sName', 'Ignatius Shixwameni'), ('p', 'http://www.wikidata.org/prop/direct/P102'), ('pName', 'member of political party'), ('o', 'http://www.wikidata.org/entity/Q1129391'), ('oName', "All People's Party")]
# [('s', 'http://www.wikidata.org/entity/Q16194214'), ('sName', 'Mophato Monyake'), ('p', 'http://www.wikidata.org/prop/direct/P102'), ('pName', 'member of political party'), ('o', 'http://www.wikidata.org/entity/Q1346132'), ('oName', 'All Basotho Convention')]
# [('s', 'http://www.wikidata.org/entity/Q3660117'), ('sName', 'Carlos Pizarro Leongómez'), ('p', 'http://www.wikidata.org/prop/direct/P102'), ('pName', 'member of political party'), ('o', 'http://www.wikidata.org/entity/Q1789014'), ('oName', '19th of April Movement')]
# [('s', 'http://www.wikidata.org/entity/Q1567660'), ('sName', 'Hae Phoofolo'), ('p', 'http://www.wikidata.org/prop/direct/P102'), ('pName', 'member of political party'), ('o', 'http://www.wikidata.org/entity/Q1346132'), ('oName', 'All Basotho Convention')]
# [('s', 'http://www.wikidata.org/entity/Q4752142'), ('sName', 'Anatol Arhire'), ('p', 'http://www.wikidata.org/prop/direct/P102'), ('pName', 'member of political party'), ('o', 'http://www.wikidata.org/entity/Q1280031'), ('oName', 'Alliance for European Integration')]
# 100

# %%
# Consider the tennis players born after 1975, return who won more Grand Slams and cut the result to the top-10 (the result set must be a list of triples player IRI, label and #victories).
# Q1426 = Roger Federer
# wdt:P1344 (participant in)
# wdt:P2522 (victory)
#[('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('o', 'http://www.wikidata.org/entity/P569'), ('oName', 'date of birth')]
# 1) getting winners dob 

queryString = """

SELECT DISTINCT ?s ?sName ?p ?pName ?o ?oName
WHERE {
   # ?s ?p ?o.
   # ?s sc:name ?sName.
   # ?p sc:name ?pName.
   # ?o sc:name ?oName.
   
   
   # today filter with regex not working
   # FILTER (REGEX(?pName,"year","i"))
   
   #it never returns the result if un-comment the filter
   #FILTER (?p not in (wdt:P2922, wdt:P991))
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('s', 'http://www.wikidata.org/entity/Q95452024'), ('sName', 'Template:Vice Presidents of the Maldives'), ('p', 'http://www.wikidata.org/prop/direct/P1423'), ('pName', 'template has topic'), ('o', 'http://www.wikidata.org/entity/Q10999435'), ('oName', 'Vice President of the Maldives')]
# [('s', 'http://www.wikidata.org/entity/Q25752552'), ('sName', 'Template:2001 in Europe'), ('p', 'http://www.wikidata.org/prop/direct/P1423'), ('pName', 'template has topic'), ('o', 'http://www.wikidata.org/entity/Q17111750'), ('oName', '2001 in Europe')]
# [('s', 'http://www.wikidata.org/entity/Q6675314'), ('sName', 'Template:Alcest'), ('p', 'http://www.wikidata.org/prop/direct/P1423'), ('pName', 'template has topic'), ('o', 'http://www.wikidata.org/entity/Q1517060'), ('oName', 'Alcest')]
# [('s', 'http://www.wikidata.org/entity/Q22785857'), ('sName', 'Template:2006 in Europe'), ('p', 'http://www.wikidata.org/prop/direct/P1423'), ('pName', 'template has topic'), ('o', 'http://www.wikidata.org/entity/Q17111782'), ('oName', '2006 in Europe')]
# [('s', 'http://www.wikidata.org/entity/Q85816744'), ('sName', 'Yodli'), ('p', 'http://www.wikidata.org/prop/direct/P1268'), ('pName', 'represents'), ('o', 'http://www.wikidata.org/entity/Q1053559'), ('oName', '2020 Winter Youth Olympics')]
# [('s', 'http://www.wikidata.org/entity/Q1064606'), ('sName', 'President of the Maldives'), ('p', 'http://www.wikidata.org/prop/direct/P2098'), ('pName', 'substitute/deputy/replacement of office/officeholder'), ('o', 'http://www.wikidata.org/entity/Q10999435'), ('oName', 'Vice President of the Maldives')]
# [('s', 'http://www.wikidata.org/entity/Q10275776'), ('sName', 'Estação Ferroviária de Mafra'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q18483474'), ('sName', 'Telhada halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q8202323'), ('sName', 'Alcainça-Moinhos halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q8202353'), ('sName', 'Bicanho Halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q8779275'), ('sName', 'Amieira train station'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q8841005'), ('sName', 'Malveira train station'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q17267254'), ('sName', 'Fanhais halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q17267315'), ('sName', 'Cela halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q8779401'), ('sName', 'Bombarral train station'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q8840924'), ('sName', 'Leiria train station'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q8841025'), ('sName', 'Marinha Grande station'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q8841035'), ('sName', 'Martingança train station'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q8841427'), ('sName', 'Pataias train station'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q8842140'), ('sName', 'Valado train station'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q248226'), ('sName', 'Agualva-Cacém railway station'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q18482873'), ('sName', 'Fontela halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q18482882'), ('sName', 'Fontela-A halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q18482941'), ('sName', 'Jerumelo halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q18483298'), ('sName', 'Salir do Porto halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q18483365'), ('sName', 'Sapataria Halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q800752'), ('sName', 'Figueira da Foz train station'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q8841452'), ('sName', 'Pero Negro train station'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q8841387'), ('sName', 'Outeiro train station'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q10275790'), ('sName', 'Sabugo train station'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q16781965'), ('sName', 'Pedra Furada halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q16781966'), ('sName', 'Telhal halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q17000336'), ('sName', 'Óbidos halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q587866'), ('sName', 'Estação Ferroviária de Caldas da Rainha'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q18482975'), ('sName', 'Lares halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q557982'), ('sName', 'Bifurcação de Lares train station'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q10275797'), ('sName', 'São Martinho do Porto train station'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q18482831'), ('sName', 'Famalicão da Nazaré halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q8841053'), ('sName', 'Mira Sintra-Meleças train station'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q10275778'), ('sName', 'Monte Real train station'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q18482642'), ('sName', 'Carriço halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q18482848'), ('sName', 'Feliteira halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q18482932'), ('sName', 'Guia halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q19702819'), ('sName', 'Monte Redondo halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q19702893'), ('sName', 'Zibreira halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q5552454'), ('sName', 'Dois Porto train station'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q8840980'), ('sName', 'Louriçal train station'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q18483271'), ('sName', 'Regueira de Pontes halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q8841573'), ('sName', 'Ramalhal train station'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q8842080'), ('sName', 'Torres Vedras train station'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q18483280'), ('sName', 'Ribeira de Seiça halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q19702853'), ('sName', 'Runa halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q18483456'), ('sName', 'São Mamede halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q38780585'), ('sName', 'First Minister of British Honduras'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q1643555'), ('oName', 'British Honduras')]
# [('s', 'http://www.wikidata.org/entity/Q26691790'), ('sName', 'mayor of Sant Pere Sallavinera'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q15967'), ('oName', 'Sant Pere Sallavinera')]
# [('s', 'http://www.wikidata.org/entity/Q105998262'), ('sName', 'Mayor of Star City'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q1419655'), ('oName', 'Star City')]
# [('s', 'http://www.wikidata.org/entity/Q108080825'), ('sName', 'Attorney-General of British Honduras'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q1643555'), ('oName', 'British Honduras')]
# [('s', 'http://www.wikidata.org/entity/Q26691184'), ('sName', 'mayor of Ripollet'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q13933'), ('oName', 'Ripollet')]
# [('s', 'http://www.wikidata.org/entity/Q56438477'), ('sName', 'mayor of Itano'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q1350904'), ('oName', 'Itano')]
# [('s', 'http://www.wikidata.org/entity/Q59773367'), ('sName', 'Arbúcies city councillor'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q13010'), ('oName', 'Arbúcies')]
# [('s', 'http://www.wikidata.org/entity/Q11907924'), ('sName', 'Flag of Ripollet'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q13933'), ('oName', 'Ripollet')]
# [('s', 'http://www.wikidata.org/entity/Q105514924'), ('sName', 'Ripollet results in 2021 Catalan parliamentary election'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q13933'), ('oName', 'Ripollet')]
# [('s', 'http://www.wikidata.org/entity/Q26695213'), ('sName', 'mayor of Pedreguer'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q1750923'), ('oName', 'Pedreguer')]
# [('s', 'http://www.wikidata.org/entity/Q44952776'), ('sName', 'Catalan regional election 2015 in Sant Pere Sallavinera'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q15967'), ('oName', 'Sant Pere Sallavinera')]
# [('s', 'http://www.wikidata.org/entity/Q101978391'), ('sName', 'Regional Regulation of Melawi Regency Number 04 Year 2018'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q14162'), ('oName', 'Melawi')]
# [('s', 'http://www.wikidata.org/entity/Q11481685'), ('sName', 'Hitachi Kokubunji'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q1055353'), ('oName', 'Hitachi Province')]
# [('s', 'http://www.wikidata.org/entity/Q26691392'), ('sName', 'mayor of Zalduendo de Álava'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q1443609'), ('oName', 'Zalduondo')]
# [('s', 'http://www.wikidata.org/entity/Q26695389'), ('sName', 'mayor of Cehegín'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q1757489'), ('oName', 'Cehegín')]
# [('s', 'http://www.wikidata.org/entity/Q62051046'), ('sName', 'Legislative Assembly of British Honduras'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q1643555'), ('oName', 'British Honduras')]
# [('s', 'http://www.wikidata.org/entity/Q26690765'), ('sName', 'mayor of Arbúcies'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q13010'), ('oName', 'Arbúcies')]
# [('s', 'http://www.wikidata.org/entity/Q105515175'), ('sName', 'Arbúcies results in 2021 Catalan parliamentary election'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q13010'), ('oName', 'Arbúcies')]
# [('s', 'http://www.wikidata.org/entity/Q44914898'), ('sName', 'Catalan regional election 2015 in Ripollet'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q13933'), ('oName', 'Ripollet')]
# [('s', 'http://www.wikidata.org/entity/Q45023173'), ('sName', 'Catalan regional election 2015 in Arbúcies'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q13010'), ('oName', 'Arbúcies')]
# [('s', 'http://www.wikidata.org/entity/Q56402053'), ('sName', 'Flag of Sant Pere Sallavinera'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q15967'), ('oName', 'Sant Pere Sallavinera')]
# [('s', 'http://www.wikidata.org/entity/Q56437866'), ('sName', 'mayor of Toyoyama'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q1345562'), ('oName', 'Toyoyama')]
# [('s', 'http://www.wikidata.org/entity/Q105514933'), ('sName', 'Sant Pere Sallavinera results in 2021 Catalan parliamentary election'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q15967'), ('oName', 'Sant Pere Sallavinera')]
# [('s', 'http://www.wikidata.org/entity/Q105482504'), ('sName', 'Arbúcies results in 2017 Catalan parliamentary election'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q13010'), ('oName', 'Arbúcies')]
# [('s', 'http://www.wikidata.org/entity/Q105482709'), ('sName', 'Ripollet results in 2017 Catalan parliamentary election'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q13933'), ('oName', 'Ripollet')]
# [('s', 'http://www.wikidata.org/entity/Q11481689'), ('sName', 'Hitachinokuni Sōshagū'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q1055353'), ('oName', 'Hitachi Province')]
# [('s', 'http://www.wikidata.org/entity/Q105481195'), ('sName', 'Sant Pere Sallavinera results in 2017 Catalan parliamentary election'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q15967'), ('oName', 'Sant Pere Sallavinera')]
# [('s', 'http://www.wikidata.org/entity/Q19294986'), ('sName', 'Louis Berlioz'), ('p', 'http://www.wikidata.org/prop/direct/P101'), ('pName', 'field of work'), ('o', 'http://www.wikidata.org/entity/Q121713'), ('oName', 'acupuncture')]
# [('s', 'http://www.wikidata.org/entity/Q64392269'), ('sName', 'Ian Gough'), ('p', 'http://www.wikidata.org/prop/direct/P101'), ('pName', 'field of work'), ('o', 'http://www.wikidata.org/entity/Q11497309'), ('oName', 'economic support')]
# [('s', 'http://www.wikidata.org/entity/Q19957642'), ('sName', 'Ruby Duncan'), ('p', 'http://www.wikidata.org/prop/direct/P101'), ('pName', 'field of work'), ('o', 'http://www.wikidata.org/entity/Q11497309'), ('oName', 'economic support')]
# [('s', 'http://www.wikidata.org/entity/Q81425306'), ('sName', 'Physiotherapy Douma'), ('p', 'http://www.wikidata.org/prop/direct/P101'), ('pName', 'field of work'), ('o', 'http://www.wikidata.org/entity/Q121713'), ('oName', 'acupuncture')]
# [('s', 'http://www.wikidata.org/entity/Q15809258'), ('sName', 'Healer of Berne'), ('p', 'http://www.wikidata.org/prop/direct/P101'), ('pName', 'field of work'), ('o', 'http://www.wikidata.org/entity/Q121713'), ('oName', 'acupuncture')]
# [('s', 'http://www.wikidata.org/entity/Q66535461'), ('sName', 'Emmanuel Kreike'), ('p', 'http://www.wikidata.org/prop/direct/P101'), ('pName', 'field of work'), ('o', 'http://www.wikidata.org/entity/Q11497309'), ('oName', 'economic support')]
# [('s', 'http://www.wikidata.org/entity/Q6066216'), ('sName', 'Ira Rubinoff'), ('p', 'http://www.wikidata.org/prop/direct/P101'), ('pName', 'field of work'), ('o', 'http://www.wikidata.org/entity/Q1673980'), ('oName', 'Smithsonian Tropical Research Institute')]
# [('s', 'http://www.wikidata.org/entity/Q55600270'), ('sName', 'Élise Boghossian'), ('p', 'http://www.wikidata.org/prop/direct/P101'), ('pName', 'field of work'), ('o', 'http://www.wikidata.org/entity/Q121713'), ('oName', 'acupuncture')]
# [('s', 'http://www.wikidata.org/entity/Q9044036'), ('sName', 'Su Yu-chang'), ('p', 'http://www.wikidata.org/prop/direct/P101'), ('pName', 'field of work'), ('o', 'http://www.wikidata.org/entity/Q121713'), ('oName', 'acupuncture')]
# [('s', 'http://www.wikidata.org/entity/Q17107163'), ('sName', 'Vilhelm Schjelderup'), ('p', 'http://www.wikidata.org/prop/direct/P101'), ('pName', 'field of work'), ('o', 'http://www.wikidata.org/entity/Q121713'), ('oName', 'acupuncture')]
# [('s', 'http://www.wikidata.org/entity/Q97147261'), ('sName', 'Clinics Dr. Erler'), ('p', 'http://www.wikidata.org/prop/direct/P101'), ('pName', 'field of work'), ('o', 'http://www.wikidata.org/entity/Q121713'), ('oName', 'acupuncture')]
# [('s', 'http://www.wikidata.org/entity/Q64175666'), ('sName', 'Jeremy Ross'), ('p', 'http://www.wikidata.org/prop/direct/P101'), ('pName', 'field of work'), ('o', 'http://www.wikidata.org/entity/Q121713'), ('oName', 'acupuncture')]
# [('s', 'http://www.wikidata.org/entity/Q96579961'), ('sName', 'Sana Clinic Nuremberg'), ('p', 'http://www.wikidata.org/prop/direct/P101'), ('pName', 'field of work'), ('o', 'http://www.wikidata.org/entity/Q121713'), ('oName', 'acupuncture')]
# [('s', 'http://www.wikidata.org/entity/Q47544113'), ('sName', 'Maesiah Thabane'), ('p', 'http://www.wikidata.org/prop/direct/P102'), ('pName', 'member of political party'), ('o', 'http://www.wikidata.org/entity/Q1346132'), ('oName', 'All Basotho Convention')]
# [('s', 'http://www.wikidata.org/entity/Q9092970'), ('sName', 'Vera Grabe'), ('p', 'http://www.wikidata.org/prop/direct/P102'), ('pName', 'member of political party'), ('o', 'http://www.wikidata.org/entity/Q1789014'), ('oName', '19th of April Movement')]
# [('s', 'http://www.wikidata.org/entity/Q5992796'), ('sName', 'Ignatius Shixwameni'), ('p', 'http://www.wikidata.org/prop/direct/P102'), ('pName', 'member of political party'), ('o', 'http://www.wikidata.org/entity/Q1129391'), ('oName', "All People's Party")]
# [('s', 'http://www.wikidata.org/entity/Q16194214'), ('sName', 'Mophato Monyake'), ('p', 'http://www.wikidata.org/prop/direct/P102'), ('pName', 'member of political party'), ('o', 'http://www.wikidata.org/entity/Q1346132'), ('oName', 'All Basotho Convention')]
# [('s', 'http://www.wikidata.org/entity/Q3660117'), ('sName', 'Carlos Pizarro Leongómez'), ('p', 'http://www.wikidata.org/prop/direct/P102'), ('pName', 'member of political party'), ('o', 'http://www.wikidata.org/entity/Q1789014'), ('oName', '19th of April Movement')]
# [('s', 'http://www.wikidata.org/entity/Q1567660'), ('sName', 'Hae Phoofolo'), ('p', 'http://www.wikidata.org/prop/direct/P102'), ('pName', 'member of political party'), ('o', 'http://www.wikidata.org/entity/Q1346132'), ('oName', 'All Basotho Convention')]
# [('s', 'http://www.wikidata.org/entity/Q4752142'), ('sName', 'Anatol Arhire'), ('p', 'http://www.wikidata.org/prop/direct/P102'), ('pName', 'member of political party'), ('o', 'http://www.wikidata.org/entity/Q1280031'), ('oName', 'Alliance for European Integration')]
# 100

# %%
# Consider the tennis players born after 1975, return who won more Grand Slams and cut the result to the top-10 (the result set must be a list of triples player IRI, label and #victories).
# Q1426 = Roger Federer
# wdt:P1344 (participant in)
# wdt:P2522 (victory)
#[('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('o', 'http://www.wikidata.org/entity/P569'), ('oName', 'date of birth')]
# 1) getting winners dob 

queryString = """

SELECT DISTINCT ?s ?sName ?p ?pName ?o ?oName
WHERE {
   # ?s ?p ?o.
   # ?s sc:name ?sName.
   # ?p sc:name ?pName.
   # ?o sc:name ?oName.
   
   
   #today filter with regex not working
   #FILTER (REGEX(?pName,"year","i"))
   
   #it never returns the result if un-comment the filter
   #FILTER (?p not in (wdt:P2922, wdt:P837))
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('s', 'http://www.wikidata.org/entity/Q95452024'), ('sName', 'Template:Vice Presidents of the Maldives'), ('p', 'http://www.wikidata.org/prop/direct/P1423'), ('pName', 'template has topic'), ('o', 'http://www.wikidata.org/entity/Q10999435'), ('oName', 'Vice President of the Maldives')]
# [('s', 'http://www.wikidata.org/entity/Q25752552'), ('sName', 'Template:2001 in Europe'), ('p', 'http://www.wikidata.org/prop/direct/P1423'), ('pName', 'template has topic'), ('o', 'http://www.wikidata.org/entity/Q17111750'), ('oName', '2001 in Europe')]
# [('s', 'http://www.wikidata.org/entity/Q6675314'), ('sName', 'Template:Alcest'), ('p', 'http://www.wikidata.org/prop/direct/P1423'), ('pName', 'template has topic'), ('o', 'http://www.wikidata.org/entity/Q1517060'), ('oName', 'Alcest')]
# [('s', 'http://www.wikidata.org/entity/Q22785857'), ('sName', 'Template:2006 in Europe'), ('p', 'http://www.wikidata.org/prop/direct/P1423'), ('pName', 'template has topic'), ('o', 'http://www.wikidata.org/entity/Q17111782'), ('oName', '2006 in Europe')]
# [('s', 'http://www.wikidata.org/entity/Q85816744'), ('sName', 'Yodli'), ('p', 'http://www.wikidata.org/prop/direct/P1268'), ('pName', 'represents'), ('o', 'http://www.wikidata.org/entity/Q1053559'), ('oName', '2020 Winter Youth Olympics')]
# [('s', 'http://www.wikidata.org/entity/Q1064606'), ('sName', 'President of the Maldives'), ('p', 'http://www.wikidata.org/prop/direct/P2098'), ('pName', 'substitute/deputy/replacement of office/officeholder'), ('o', 'http://www.wikidata.org/entity/Q10999435'), ('oName', 'Vice President of the Maldives')]
# [('s', 'http://www.wikidata.org/entity/Q10275776'), ('sName', 'Estação Ferroviária de Mafra'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q18483474'), ('sName', 'Telhada halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q8202323'), ('sName', 'Alcainça-Moinhos halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q8202353'), ('sName', 'Bicanho Halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q8779275'), ('sName', 'Amieira train station'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q8841005'), ('sName', 'Malveira train station'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q17267254'), ('sName', 'Fanhais halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q17267315'), ('sName', 'Cela halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q8779401'), ('sName', 'Bombarral train station'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q8840924'), ('sName', 'Leiria train station'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q8841025'), ('sName', 'Marinha Grande station'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q8841035'), ('sName', 'Martingança train station'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q8841427'), ('sName', 'Pataias train station'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q8842140'), ('sName', 'Valado train station'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q248226'), ('sName', 'Agualva-Cacém railway station'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q18482873'), ('sName', 'Fontela halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q18482882'), ('sName', 'Fontela-A halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q18482941'), ('sName', 'Jerumelo halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q18483298'), ('sName', 'Salir do Porto halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q18483365'), ('sName', 'Sapataria Halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q800752'), ('sName', 'Figueira da Foz train station'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q8841452'), ('sName', 'Pero Negro train station'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q8841387'), ('sName', 'Outeiro train station'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q10275790'), ('sName', 'Sabugo train station'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q16781965'), ('sName', 'Pedra Furada halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q16781966'), ('sName', 'Telhal halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q17000336'), ('sName', 'Óbidos halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q587866'), ('sName', 'Estação Ferroviária de Caldas da Rainha'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q18482975'), ('sName', 'Lares halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q557982'), ('sName', 'Bifurcação de Lares train station'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q10275797'), ('sName', 'São Martinho do Porto train station'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q18482831'), ('sName', 'Famalicão da Nazaré halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q8841053'), ('sName', 'Mira Sintra-Meleças train station'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q10275778'), ('sName', 'Monte Real train station'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q18482642'), ('sName', 'Carriço halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q18482848'), ('sName', 'Feliteira halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q18482932'), ('sName', 'Guia halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q19702819'), ('sName', 'Monte Redondo halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q19702893'), ('sName', 'Zibreira halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q5552454'), ('sName', 'Dois Porto train station'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q8840980'), ('sName', 'Louriçal train station'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q18483271'), ('sName', 'Regueira de Pontes halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q8841573'), ('sName', 'Ramalhal train station'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q8842080'), ('sName', 'Torres Vedras train station'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q18483280'), ('sName', 'Ribeira de Seiça halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q19702853'), ('sName', 'Runa halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q18483456'), ('sName', 'São Mamede halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q38780585'), ('sName', 'First Minister of British Honduras'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q1643555'), ('oName', 'British Honduras')]
# [('s', 'http://www.wikidata.org/entity/Q26691790'), ('sName', 'mayor of Sant Pere Sallavinera'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q15967'), ('oName', 'Sant Pere Sallavinera')]
# [('s', 'http://www.wikidata.org/entity/Q105998262'), ('sName', 'Mayor of Star City'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q1419655'), ('oName', 'Star City')]
# [('s', 'http://www.wikidata.org/entity/Q108080825'), ('sName', 'Attorney-General of British Honduras'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q1643555'), ('oName', 'British Honduras')]
# [('s', 'http://www.wikidata.org/entity/Q26691184'), ('sName', 'mayor of Ripollet'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q13933'), ('oName', 'Ripollet')]
# [('s', 'http://www.wikidata.org/entity/Q56438477'), ('sName', 'mayor of Itano'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q1350904'), ('oName', 'Itano')]
# [('s', 'http://www.wikidata.org/entity/Q59773367'), ('sName', 'Arbúcies city councillor'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q13010'), ('oName', 'Arbúcies')]
# [('s', 'http://www.wikidata.org/entity/Q11907924'), ('sName', 'Flag of Ripollet'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q13933'), ('oName', 'Ripollet')]
# [('s', 'http://www.wikidata.org/entity/Q105514924'), ('sName', 'Ripollet results in 2021 Catalan parliamentary election'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q13933'), ('oName', 'Ripollet')]
# [('s', 'http://www.wikidata.org/entity/Q26695213'), ('sName', 'mayor of Pedreguer'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q1750923'), ('oName', 'Pedreguer')]
# [('s', 'http://www.wikidata.org/entity/Q44952776'), ('sName', 'Catalan regional election 2015 in Sant Pere Sallavinera'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q15967'), ('oName', 'Sant Pere Sallavinera')]
# [('s', 'http://www.wikidata.org/entity/Q101978391'), ('sName', 'Regional Regulation of Melawi Regency Number 04 Year 2018'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q14162'), ('oName', 'Melawi')]
# [('s', 'http://www.wikidata.org/entity/Q11481685'), ('sName', 'Hitachi Kokubunji'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q1055353'), ('oName', 'Hitachi Province')]
# [('s', 'http://www.wikidata.org/entity/Q26691392'), ('sName', 'mayor of Zalduendo de Álava'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q1443609'), ('oName', 'Zalduondo')]
# [('s', 'http://www.wikidata.org/entity/Q26695389'), ('sName', 'mayor of Cehegín'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q1757489'), ('oName', 'Cehegín')]
# [('s', 'http://www.wikidata.org/entity/Q62051046'), ('sName', 'Legislative Assembly of British Honduras'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q1643555'), ('oName', 'British Honduras')]
# [('s', 'http://www.wikidata.org/entity/Q26690765'), ('sName', 'mayor of Arbúcies'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q13010'), ('oName', 'Arbúcies')]
# [('s', 'http://www.wikidata.org/entity/Q105515175'), ('sName', 'Arbúcies results in 2021 Catalan parliamentary election'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q13010'), ('oName', 'Arbúcies')]
# [('s', 'http://www.wikidata.org/entity/Q44914898'), ('sName', 'Catalan regional election 2015 in Ripollet'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q13933'), ('oName', 'Ripollet')]
# [('s', 'http://www.wikidata.org/entity/Q45023173'), ('sName', 'Catalan regional election 2015 in Arbúcies'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q13010'), ('oName', 'Arbúcies')]
# [('s', 'http://www.wikidata.org/entity/Q56402053'), ('sName', 'Flag of Sant Pere Sallavinera'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q15967'), ('oName', 'Sant Pere Sallavinera')]
# [('s', 'http://www.wikidata.org/entity/Q56437866'), ('sName', 'mayor of Toyoyama'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q1345562'), ('oName', 'Toyoyama')]
# [('s', 'http://www.wikidata.org/entity/Q105514933'), ('sName', 'Sant Pere Sallavinera results in 2021 Catalan parliamentary election'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q15967'), ('oName', 'Sant Pere Sallavinera')]
# [('s', 'http://www.wikidata.org/entity/Q105482504'), ('sName', 'Arbúcies results in 2017 Catalan parliamentary election'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q13010'), ('oName', 'Arbúcies')]
# [('s', 'http://www.wikidata.org/entity/Q105482709'), ('sName', 'Ripollet results in 2017 Catalan parliamentary election'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q13933'), ('oName', 'Ripollet')]
# [('s', 'http://www.wikidata.org/entity/Q11481689'), ('sName', 'Hitachinokuni Sōshagū'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q1055353'), ('oName', 'Hitachi Province')]
# [('s', 'http://www.wikidata.org/entity/Q105481195'), ('sName', 'Sant Pere Sallavinera results in 2017 Catalan parliamentary election'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q15967'), ('oName', 'Sant Pere Sallavinera')]
# [('s', 'http://www.wikidata.org/entity/Q19294986'), ('sName', 'Louis Berlioz'), ('p', 'http://www.wikidata.org/prop/direct/P101'), ('pName', 'field of work'), ('o', 'http://www.wikidata.org/entity/Q121713'), ('oName', 'acupuncture')]
# [('s', 'http://www.wikidata.org/entity/Q64392269'), ('sName', 'Ian Gough'), ('p', 'http://www.wikidata.org/prop/direct/P101'), ('pName', 'field of work'), ('o', 'http://www.wikidata.org/entity/Q11497309'), ('oName', 'economic support')]
# [('s', 'http://www.wikidata.org/entity/Q19957642'), ('sName', 'Ruby Duncan'), ('p', 'http://www.wikidata.org/prop/direct/P101'), ('pName', 'field of work'), ('o', 'http://www.wikidata.org/entity/Q11497309'), ('oName', 'economic support')]
# [('s', 'http://www.wikidata.org/entity/Q81425306'), ('sName', 'Physiotherapy Douma'), ('p', 'http://www.wikidata.org/prop/direct/P101'), ('pName', 'field of work'), ('o', 'http://www.wikidata.org/entity/Q121713'), ('oName', 'acupuncture')]
# [('s', 'http://www.wikidata.org/entity/Q15809258'), ('sName', 'Healer of Berne'), ('p', 'http://www.wikidata.org/prop/direct/P101'), ('pName', 'field of work'), ('o', 'http://www.wikidata.org/entity/Q121713'), ('oName', 'acupuncture')]
# [('s', 'http://www.wikidata.org/entity/Q66535461'), ('sName', 'Emmanuel Kreike'), ('p', 'http://www.wikidata.org/prop/direct/P101'), ('pName', 'field of work'), ('o', 'http://www.wikidata.org/entity/Q11497309'), ('oName', 'economic support')]
# [('s', 'http://www.wikidata.org/entity/Q6066216'), ('sName', 'Ira Rubinoff'), ('p', 'http://www.wikidata.org/prop/direct/P101'), ('pName', 'field of work'), ('o', 'http://www.wikidata.org/entity/Q1673980'), ('oName', 'Smithsonian Tropical Research Institute')]
# [('s', 'http://www.wikidata.org/entity/Q55600270'), ('sName', 'Élise Boghossian'), ('p', 'http://www.wikidata.org/prop/direct/P101'), ('pName', 'field of work'), ('o', 'http://www.wikidata.org/entity/Q121713'), ('oName', 'acupuncture')]
# [('s', 'http://www.wikidata.org/entity/Q9044036'), ('sName', 'Su Yu-chang'), ('p', 'http://www.wikidata.org/prop/direct/P101'), ('pName', 'field of work'), ('o', 'http://www.wikidata.org/entity/Q121713'), ('oName', 'acupuncture')]
# [('s', 'http://www.wikidata.org/entity/Q17107163'), ('sName', 'Vilhelm Schjelderup'), ('p', 'http://www.wikidata.org/prop/direct/P101'), ('pName', 'field of work'), ('o', 'http://www.wikidata.org/entity/Q121713'), ('oName', 'acupuncture')]
# [('s', 'http://www.wikidata.org/entity/Q97147261'), ('sName', 'Clinics Dr. Erler'), ('p', 'http://www.wikidata.org/prop/direct/P101'), ('pName', 'field of work'), ('o', 'http://www.wikidata.org/entity/Q121713'), ('oName', 'acupuncture')]
# [('s', 'http://www.wikidata.org/entity/Q64175666'), ('sName', 'Jeremy Ross'), ('p', 'http://www.wikidata.org/prop/direct/P101'), ('pName', 'field of work'), ('o', 'http://www.wikidata.org/entity/Q121713'), ('oName', 'acupuncture')]
# [('s', 'http://www.wikidata.org/entity/Q96579961'), ('sName', 'Sana Clinic Nuremberg'), ('p', 'http://www.wikidata.org/prop/direct/P101'), ('pName', 'field of work'), ('o', 'http://www.wikidata.org/entity/Q121713'), ('oName', 'acupuncture')]
# [('s', 'http://www.wikidata.org/entity/Q47544113'), ('sName', 'Maesiah Thabane'), ('p', 'http://www.wikidata.org/prop/direct/P102'), ('pName', 'member of political party'), ('o', 'http://www.wikidata.org/entity/Q1346132'), ('oName', 'All Basotho Convention')]
# [('s', 'http://www.wikidata.org/entity/Q9092970'), ('sName', 'Vera Grabe'), ('p', 'http://www.wikidata.org/prop/direct/P102'), ('pName', 'member of political party'), ('o', 'http://www.wikidata.org/entity/Q1789014'), ('oName', '19th of April Movement')]
# [('s', 'http://www.wikidata.org/entity/Q5992796'), ('sName', 'Ignatius Shixwameni'), ('p', 'http://www.wikidata.org/prop/direct/P102'), ('pName', 'member of political party'), ('o', 'http://www.wikidata.org/entity/Q1129391'), ('oName', "All People's Party")]
# [('s', 'http://www.wikidata.org/entity/Q16194214'), ('sName', 'Mophato Monyake'), ('p', 'http://www.wikidata.org/prop/direct/P102'), ('pName', 'member of political party'), ('o', 'http://www.wikidata.org/entity/Q1346132'), ('oName', 'All Basotho Convention')]
# [('s', 'http://www.wikidata.org/entity/Q3660117'), ('sName', 'Carlos Pizarro Leongómez'), ('p', 'http://www.wikidata.org/prop/direct/P102'), ('pName', 'member of political party'), ('o', 'http://www.wikidata.org/entity/Q1789014'), ('oName', '19th of April Movement')]
# [('s', 'http://www.wikidata.org/entity/Q1567660'), ('sName', 'Hae Phoofolo'), ('p', 'http://www.wikidata.org/prop/direct/P102'), ('pName', 'member of political party'), ('o', 'http://www.wikidata.org/entity/Q1346132'), ('oName', 'All Basotho Convention')]
# [('s', 'http://www.wikidata.org/entity/Q4752142'), ('sName', 'Anatol Arhire'), ('p', 'http://www.wikidata.org/prop/direct/P102'), ('pName', 'member of political party'), ('o', 'http://www.wikidata.org/entity/Q1280031'), ('oName', 'Alliance for European Integration')]
# 100

# %%
# BIRTHDAY FOUND

# %%
# Consider the tennis players born after 1975, return who won more Grand Slams and cut the result to the top-10 (the result set must be a list of triples player IRI, label and #victories).
# Q1426 = Roger Federer
# wdt:P1344 (participant in)
# wdt:P2522 (victory)
#[('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('o', 'http://www.wikidata.org/entity/P569'), ('oName', 'date of birth')]
# 1) getting winners dob 

queryString = """

SELECT DISTINCT ?s ?sName ?p ?pName ?o ?oName
WHERE {
   # ?s ?p ?o.
   # ?s sc:name ?sName.
   # ?p sc:name ?pName.
   # ?o sc:name ?oName.
   
   # today filter with regex not working
   #FILTER (REGEX(?pName,"birth","i"))
   FILTER (?p not in (wdt:P19, wdt:P837))
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('s', 'http://www.wikidata.org/entity/Q10275776'), ('sName', 'Estação Ferroviária de Mafra'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q11235194'), ('sName', 'Tokyo Solamachi'), ('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q11497641'), ('oName', 'Oshiage')]
# [('s', 'http://www.wikidata.org/entity/Q15628796'), ('sName', 'Pedro Ponce de Cabrera'), ('p', 'http://www.wikidata.org/prop/direct/P119'), ('pName', 'place of burial'), ('o', 'http://www.wikidata.org/entity/Q16608610'), ('oName', 'Monastery of Santa María de Nogales')]
# [('s', 'http://www.wikidata.org/entity/Q18483474'), ('sName', 'Telhada halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q18531652'), ('sName', 'William Walker'), ('p', 'http://www.wikidata.org/prop/direct/P1343'), ('pName', 'described by source'), ('o', 'http://www.wikidata.org/entity/Q17037575'), ('oName', 'Oxford Biography Index')]
# [('s', 'http://www.wikidata.org/entity/Q4829629'), ('sName', 'Awa-Ōmiya Station'), ('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q1350904'), ('oName', 'Itano')]
# [('s', 'http://www.wikidata.org/entity/Q7371392'), ('sName', 'Route 1'), ('p', 'http://www.wikidata.org/prop/direct/P126'), ('pName', 'maintained by'), ('o', 'http://www.wikidata.org/entity/Q11415304'), ('oName', 'Nagoya Expressway Public Corporation')]
# [('s', 'http://www.wikidata.org/entity/Q8134074'), ('sName', 'Sumida Aquarium'), ('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q11497641'), ('oName', 'Oshiage')]
# [('s', 'http://www.wikidata.org/entity/Q8146191'), ('sName', 'Nanga Pinoh'), ('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q14162'), ('oName', 'Melawi')]
# [('s', 'http://www.wikidata.org/entity/Q8167413'), ('sName', 'Guguak VIII Koto'), ('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q12403132'), ('oName', 'Guguak')]
# [('s', 'http://www.wikidata.org/entity/Q8183600'), ('sName', 'Agrostroj Pelhřimov'), ('p', 'http://www.wikidata.org/prop/direct/P127'), ('pName', 'owned by'), ('o', 'http://www.wikidata.org/entity/Q100343342'), ('oName', 'Lubomír Stoklásek')]
# [('s', 'http://www.wikidata.org/entity/Q8183671'), ('sName', 'Aarão de Lacerda'), ('p', 'http://www.wikidata.org/prop/direct/P108'), ('pName', 'employer'), ('o', 'http://www.wikidata.org/entity/Q10279508'), ('oName', 'Faculdade de Letras da Universidade de Coimbra')]
# [('s', 'http://www.wikidata.org/entity/Q8183671'), ('sName', 'Aarão de Lacerda'), ('p', 'http://www.wikidata.org/prop/direct/P108'), ('pName', 'employer'), ('o', 'http://www.wikidata.org/entity/Q10279509'), ('oName', 'Faculty of Arts and Humanities of the University of Porto')]
# [('s', 'http://www.wikidata.org/entity/Q8190594'), ('sName', 'Awa-Kawabata Station'), ('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q1350904'), ('oName', 'Itano')]
# [('s', 'http://www.wikidata.org/entity/Q8190673'), ('sName', 'Itano Station'), ('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q1350904'), ('oName', 'Itano')]
# [('s', 'http://www.wikidata.org/entity/Q8190939'), ('sName', 'Calaf-Salavinera Airport'), ('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q15967'), ('oName', 'Sant Pere Sallavinera')]
# [('s', 'http://www.wikidata.org/entity/Q8194022'), ('sName', 'Tomonoura'), ('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q17238551'), ('oName', 'Tomo')]
# [('s', 'http://www.wikidata.org/entity/Q8195084'), ('sName', 'mahjong tile'), ('p', 'http://www.wikidata.org/prop/direct/P1269'), ('pName', 'facet of'), ('o', 'http://www.wikidata.org/entity/Q12263'), ('oName', 'mahjong')]
# [('s', 'http://www.wikidata.org/entity/Q8197013'), ('sName', 'Amancio Muñoz de Zafra'), ('p', 'http://www.wikidata.org/prop/direct/P1038'), ('pName', 'relative'), ('o', 'http://www.wikidata.org/entity/Q105753880'), ('oName', 'Mateo Egea')]
# [('s', 'http://www.wikidata.org/entity/Q8199438'), ('sName', 'Andrés de Sola'), ('p', 'http://www.wikidata.org/prop/direct/P1066'), ('pName', 'student of'), ('o', 'http://www.wikidata.org/entity/Q11686949'), ('oName', 'José Ximénez')]
# [('s', 'http://www.wikidata.org/entity/Q8200247'), ('sName', 'Annette Aiello'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('pName', 'occupation'), ('o', 'http://www.wikidata.org/entity/Q12368980'), ('oName', 'nature photographer')]
# [('s', 'http://www.wikidata.org/entity/Q8200247'), ('sName', 'Annette Aiello'), ('p', 'http://www.wikidata.org/prop/direct/P108'), ('pName', 'employer'), ('o', 'http://www.wikidata.org/entity/Q1673980'), ('oName', 'Smithsonian Tropical Research Institute')]
# [('s', 'http://www.wikidata.org/entity/Q8200777'), ('sName', 'Anthony Walker'), ('p', 'http://www.wikidata.org/prop/direct/P1343'), ('pName', 'described by source'), ('o', 'http://www.wikidata.org/entity/Q17037575'), ('oName', 'Oxford Biography Index')]
# [('s', 'http://www.wikidata.org/entity/Q8202323'), ('sName', 'Alcainça-Moinhos halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q8202353'), ('sName', 'Bicanho Halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q8213303'), ('sName', 'Bunguran Utara'), ('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q10100'), ('oName', 'Natuna')]
# [('s', 'http://www.wikidata.org/entity/Q8779275'), ('sName', 'Amieira train station'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q8841005'), ('sName', 'Malveira train station'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q95452024'), ('sName', 'Template:Vice Presidents of the Maldives'), ('p', 'http://www.wikidata.org/prop/direct/P1423'), ('pName', 'template has topic'), ('o', 'http://www.wikidata.org/entity/Q10999435'), ('oName', 'Vice President of the Maldives')]
# [('s', 'http://www.wikidata.org/entity/Q81904264'), ('sName', 'Kim Ji-min'), ('p', 'http://www.wikidata.org/prop/direct/P1344'), ('pName', 'participant in'), ('o', 'http://www.wikidata.org/entity/Q1053559'), ('oName', '2020 Winter Youth Olympics')]
# [('s', 'http://www.wikidata.org/entity/Q17211428'), ('sName', 'Shigahondōri, Nagoya'), ('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q1207964'), ('oName', 'Kita-ku')]
# [('s', 'http://www.wikidata.org/entity/Q17218089'), ('sName', 'Shimmei-chō, Nagoya'), ('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q1207964'), ('oName', 'Kita-ku')]
# [('s', 'http://www.wikidata.org/entity/Q17222169'), ('sName', 'Yanagihara, Nagoya'), ('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q1207964'), ('oName', 'Kita-ku')]
# [('s', 'http://www.wikidata.org/entity/Q17228019'), ('sName', 'Onari-tōri, Nagoya'), ('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q1207964'), ('oName', 'Kita-ku')]
# [('s', 'http://www.wikidata.org/entity/Q17482735'), ('sName', 'Turó de Montcortal'), ('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q13010'), ('oName', 'Arbúcies')]
# [('s', 'http://www.wikidata.org/entity/Q17482780'), ('sName', 'Turó de Montsoriu'), ('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q13010'), ('oName', 'Arbúcies')]
# [('s', 'http://www.wikidata.org/entity/Q17588022'), ('sName', 'Bassa de la Farga'), ('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q13010'), ('oName', 'Arbúcies')]
# [('s', 'http://www.wikidata.org/entity/Q17614805'), ('sName', 'muntanya de Can Fonoll'), ('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q13010'), ('oName', 'Arbúcies')]
# [('s', 'http://www.wikidata.org/entity/Q5289551'), ('sName', 'Dolores Piperno'), ('p', 'http://www.wikidata.org/prop/direct/P108'), ('pName', 'employer'), ('o', 'http://www.wikidata.org/entity/Q1673980'), ('oName', 'Smithsonian Tropical Research Institute')]
# [('s', 'http://www.wikidata.org/entity/Q91336419'), ('sName', 'Tommy Merlyn'), ('p', 'http://www.wikidata.org/prop/direct/P119'), ('pName', 'place of burial'), ('o', 'http://www.wikidata.org/entity/Q1419655'), ('oName', 'Star City')]
# [('s', 'http://www.wikidata.org/entity/Q91376977'), ('sName', 'Monica Munoz-Torres'), ('p', 'http://www.wikidata.org/prop/direct/P108'), ('pName', 'employer'), ('o', 'http://www.wikidata.org/entity/Q1673980'), ('oName', 'Smithsonian Tropical Research Institute')]
# [('s', 'http://www.wikidata.org/entity/Q30902089'), ('sName', 'Luis Manuel Fernández'), ('p', 'http://www.wikidata.org/prop/direct/P108'), ('pName', 'employer'), ('o', 'http://www.wikidata.org/entity/Q1475831'), ('oName', 'Venezolana de Televisión')]
# [('s', 'http://www.wikidata.org/entity/Q60684635'), ('sName', 'S. Joseph Wright'), ('p', 'http://www.wikidata.org/prop/direct/P108'), ('pName', 'employer'), ('o', 'http://www.wikidata.org/entity/Q1673980'), ('oName', 'Smithsonian Tropical Research Institute')]
# [('s', 'http://www.wikidata.org/entity/Q38780585'), ('sName', 'First Minister of British Honduras'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q1643555'), ('oName', 'British Honduras')]
# [('s', 'http://www.wikidata.org/entity/Q11325962'), ('sName', 'Hyatt Regency Kyoto'), ('p', 'http://www.wikidata.org/prop/direct/P127'), ('pName', 'owned by'), ('o', 'http://www.wikidata.org/entity/Q11292651'), ('oName', 'Orix Real Estate')]
# [('s', 'http://www.wikidata.org/entity/Q18527476'), ('sName', 'David Brown'), ('p', 'http://www.wikidata.org/prop/direct/P1343'), ('pName', 'described by source'), ('o', 'http://www.wikidata.org/entity/Q17037575'), ('oName', 'Oxford Biography Index')]
# [('s', 'http://www.wikidata.org/entity/Q10863554'), ('sName', 'Ryūgasaki Domain'), ('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q1055353'), ('oName', 'Hitachi Province')]
# [('s', 'http://www.wikidata.org/entity/Q18005572'), ('sName', "Serra d'en Pere Bord"), ('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q13010'), ('oName', 'Arbúcies')]
# [('s', 'http://www.wikidata.org/entity/Q18529777'), ('sName', 'James Brown'), ('p', 'http://www.wikidata.org/prop/direct/P1343'), ('pName', 'described by source'), ('o', 'http://www.wikidata.org/entity/Q17037575'), ('oName', 'Oxford Biography Index')]
# [('s', 'http://www.wikidata.org/entity/Q18530178'), ('sName', 'John Brown'), ('p', 'http://www.wikidata.org/prop/direct/P1343'), ('pName', 'described by source'), ('o', 'http://www.wikidata.org/entity/Q17037575'), ('oName', 'Oxford Biography Index')]
# [('s', 'http://www.wikidata.org/entity/Q18810862'), ('sName', 'John Robinson'), ('p', 'http://www.wikidata.org/prop/direct/P1343'), ('pName', 'described by source'), ('o', 'http://www.wikidata.org/entity/Q17037575'), ('oName', 'Oxford Biography Index')]
# [('s', 'http://www.wikidata.org/entity/Q18810881'), ('sName', 'John Merry Ross'), ('p', 'http://www.wikidata.org/prop/direct/P1343'), ('pName', 'described by source'), ('o', 'http://www.wikidata.org/entity/Q17037575'), ('oName', 'Oxford Biography Index')]
# [('s', 'http://www.wikidata.org/entity/Q21338376'), ('sName', 'George R. Angehr'), ('p', 'http://www.wikidata.org/prop/direct/P108'), ('pName', 'employer'), ('o', 'http://www.wikidata.org/entity/Q1673980'), ('oName', 'Smithsonian Tropical Research Institute')]
# [('s', 'http://www.wikidata.org/entity/Q108386354'), ('sName', 'William P. Leonard'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('pName', 'occupation'), ('o', 'http://www.wikidata.org/entity/Q12368980'), ('oName', 'nature photographer')]
# [('s', 'http://www.wikidata.org/entity/Q64910919'), ('sName', 'Subish Palaian'), ('p', 'http://www.wikidata.org/prop/direct/P108'), ('pName', 'employer'), ('o', 'http://www.wikidata.org/entity/Q12204508'), ('oName', 'Ajman University')]
# [('s', 'http://www.wikidata.org/entity/Q57161562'), ('sName', 'Michiel van Breugel'), ('p', 'http://www.wikidata.org/prop/direct/P108'), ('pName', 'employer'), ('o', 'http://www.wikidata.org/entity/Q1673980'), ('oName', 'Smithsonian Tropical Research Institute')]
# [('s', 'http://www.wikidata.org/entity/Q76449094'), ('sName', 'Victoria Stirnemann'), ('p', 'http://www.wikidata.org/prop/direct/P1344'), ('pName', 'participant in'), ('o', 'http://www.wikidata.org/entity/Q1053559'), ('oName', '2020 Winter Youth Olympics')]
# [('s', 'http://www.wikidata.org/entity/Q81904099'), ('sName', 'Benjamin Kapp'), ('p', 'http://www.wikidata.org/prop/direct/P1344'), ('pName', 'participant in'), ('o', 'http://www.wikidata.org/entity/Q1053559'), ('oName', '2020 Winter Youth Olympics')]
# [('s', 'http://www.wikidata.org/entity/Q1749545'), ('sName', 'Nova Zagora Municipality'), ('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q113120'), ('oName', 'Sliven Province')]
# [('s', 'http://www.wikidata.org/entity/Q3031457'), ('sName', 'Mananjary'), ('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q1462671'), ('oName', 'Vatovavy-Fitovinany')]
# [('s', 'http://www.wikidata.org/entity/Q7850092'), ('sName', 'Tsukuba district'), ('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q1055353'), ('oName', 'Hitachi Province')]
# [('s', 'http://www.wikidata.org/entity/Q24232048'), ('sName', 'Pulau Tiga Barat'), ('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q10100'), ('oName', 'Natuna')]
# [('s', 'http://www.wikidata.org/entity/Q8213242'), ('sName', 'Pulau Tiga'), ('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q10100'), ('oName', 'Natuna')]
# [('s', 'http://www.wikidata.org/entity/Q18526878'), ('sName', 'John Evans'), ('p', 'http://www.wikidata.org/prop/direct/P1343'), ('pName', 'described by source'), ('o', 'http://www.wikidata.org/entity/Q17037575'), ('oName', 'Oxford Biography Index')]
# [('s', 'http://www.wikidata.org/entity/Q18527381'), ('sName', 'John Murray'), ('p', 'http://www.wikidata.org/prop/direct/P1343'), ('pName', 'described by source'), ('o', 'http://www.wikidata.org/entity/Q17037575'), ('oName', 'Oxford Biography Index')]
# [('s', 'http://www.wikidata.org/entity/Q18527772'), ('sName', 'John Walker'), ('p', 'http://www.wikidata.org/prop/direct/P1343'), ('pName', 'described by source'), ('o', 'http://www.wikidata.org/entity/Q17037575'), ('oName', 'Oxford Biography Index')]
# [('s', 'http://www.wikidata.org/entity/Q18529684'), ('sName', 'David Davies'), ('p', 'http://www.wikidata.org/prop/direct/P1343'), ('pName', 'described by source'), ('o', 'http://www.wikidata.org/entity/Q17037575'), ('oName', 'Oxford Biography Index')]
# [('s', 'http://www.wikidata.org/entity/Q18530173'), ('sName', 'John Brown'), ('p', 'http://www.wikidata.org/prop/direct/P1343'), ('pName', 'described by source'), ('o', 'http://www.wikidata.org/entity/Q17037575'), ('oName', 'Oxford Biography Index')]
# [('s', 'http://www.wikidata.org/entity/Q18530181'), ('sName', 'John Wright Brown'), ('p', 'http://www.wikidata.org/prop/direct/P1343'), ('pName', 'described by source'), ('o', 'http://www.wikidata.org/entity/Q17037575'), ('oName', 'Oxford Biography Index')]
# [('s', 'http://www.wikidata.org/entity/Q18534214'), ('sName', 'John Taylor'), ('p', 'http://www.wikidata.org/prop/direct/P1343'), ('pName', 'described by source'), ('o', 'http://www.wikidata.org/entity/Q17037575'), ('oName', 'Oxford Biography Index')]
# [('s', 'http://www.wikidata.org/entity/Q18546621'), ('sName', 'John Roland Phillips'), ('p', 'http://www.wikidata.org/prop/direct/P1343'), ('pName', 'described by source'), ('o', 'http://www.wikidata.org/entity/Q17037575'), ('oName', 'Oxford Biography Index')]
# [('s', 'http://www.wikidata.org/entity/Q18546651'), ('sName', 'John Williams'), ('p', 'http://www.wikidata.org/prop/direct/P1343'), ('pName', 'described by source'), ('o', 'http://www.wikidata.org/entity/Q17037575'), ('oName', 'Oxford Biography Index')]
# [('s', 'http://www.wikidata.org/entity/Q18546656'), ('sName', 'John Bickerton Williams'), ('p', 'http://www.wikidata.org/prop/direct/P1343'), ('pName', 'described by source'), ('o', 'http://www.wikidata.org/entity/Q17037575'), ('oName', 'Oxford Biography Index')]
# [('s', 'http://www.wikidata.org/entity/Q7528143'), ('sName', 'Sir John Williams, 1st Baronet, of the City of London'), ('p', 'http://www.wikidata.org/prop/direct/P1343'), ('pName', 'described by source'), ('o', 'http://www.wikidata.org/entity/Q17037575'), ('oName', 'Oxford Biography Index')]
# [('s', 'http://www.wikidata.org/entity/Q18593621'), ('sName', 'William Moore'), ('p', 'http://www.wikidata.org/prop/direct/P1343'), ('pName', 'described by source'), ('o', 'http://www.wikidata.org/entity/Q17037575'), ('oName', 'Oxford Biography Index')]
# [('s', 'http://www.wikidata.org/entity/Q18729868'), ('sName', 'Entesa per Arbúcies'), ('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q13010'), ('oName', 'Arbúcies')]
# [('s', 'http://www.wikidata.org/entity/Q12475627'), ('sName', 'Belimbing, Melawi'), ('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q14162'), ('oName', 'Melawi')]
# [('s', 'http://www.wikidata.org/entity/Q8213273'), ('sName', 'Serasan'), ('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q10100'), ('oName', 'Natuna')]
# [('s', 'http://www.wikidata.org/entity/Q1905256'), ('sName', 'Martin Wikelski'), ('p', 'http://www.wikidata.org/prop/direct/P108'), ('pName', 'employer'), ('o', 'http://www.wikidata.org/entity/Q1673980'), ('oName', 'Smithsonian Tropical Research Institute')]
# [('s', 'http://www.wikidata.org/entity/Q21611757'), ('sName', 'Juan Carlos Villarreal Aguilar'), ('p', 'http://www.wikidata.org/prop/direct/P108'), ('pName', 'employer'), ('o', 'http://www.wikidata.org/entity/Q1673980'), ('oName', 'Smithsonian Tropical Research Institute')]
# [('s', 'http://www.wikidata.org/entity/Q24035454'), ('sName', 'el Vidal'), ('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q13010'), ('oName', 'Arbúcies')]
# [('s', 'http://www.wikidata.org/entity/Q57080337'), ('sName', 'David I Kline'), ('p', 'http://www.wikidata.org/prop/direct/P108'), ('pName', 'employer'), ('o', 'http://www.wikidata.org/entity/Q1673980'), ('oName', 'Smithsonian Tropical Research Institute')]
# [('s', 'http://www.wikidata.org/entity/Q44790072'), ('sName', 'Sean R. Connolly'), ('p', 'http://www.wikidata.org/prop/direct/P108'), ('pName', 'employer'), ('o', 'http://www.wikidata.org/entity/Q1673980'), ('oName', 'Smithsonian Tropical Research Institute')]
# [('s', 'http://www.wikidata.org/entity/Q60297756'), ('sName', 'Orpheus M Butler'), ('p', 'http://www.wikidata.org/prop/direct/P108'), ('pName', 'employer'), ('o', 'http://www.wikidata.org/entity/Q1673980'), ('oName', 'Smithsonian Tropical Research Institute')]
# [('s', 'http://www.wikidata.org/entity/Q19294986'), ('sName', 'Louis Berlioz'), ('p', 'http://www.wikidata.org/prop/direct/P101'), ('pName', 'field of work'), ('o', 'http://www.wikidata.org/entity/Q121713'), ('oName', 'acupuncture')]
# [('s', 'http://www.wikidata.org/entity/Q7980959'), ('sName', 'welfare fraud'), ('p', 'http://www.wikidata.org/prop/direct/P1269'), ('pName', 'facet of'), ('o', 'http://www.wikidata.org/entity/Q11497309'), ('oName', 'economic support')]
# [('s', 'http://www.wikidata.org/entity/Q7371387'), ('sName', 'Nagoya Expressway 16'), ('p', 'http://www.wikidata.org/prop/direct/P126'), ('pName', 'maintained by'), ('o', 'http://www.wikidata.org/entity/Q11415304'), ('oName', 'Nagoya Expressway Public Corporation')]
# [('s', 'http://www.wikidata.org/entity/Q80545'), ('sName', 'Oshiage Station'), ('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q11497641'), ('oName', 'Oshiage')]
# [('s', 'http://www.wikidata.org/entity/Q8191440'), ('sName', 'Nagoya Highway 11'), ('p', 'http://www.wikidata.org/prop/direct/P126'), ('pName', 'maintained by'), ('o', 'http://www.wikidata.org/entity/Q11415304'), ('oName', 'Nagoya Expressway Public Corporation')]
# [('s', 'http://www.wikidata.org/entity/Q8191440'), ('sName', 'Nagoya Highway 11'), ('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q1207964'), ('oName', 'Kita-ku')]
# [('s', 'http://www.wikidata.org/entity/Q8191440'), ('sName', 'Nagoya Highway 11'), ('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q1345562'), ('oName', 'Toyoyama')]
# [('s', 'http://www.wikidata.org/entity/Q4423406'), ('sName', 'Sliven Municipality'), ('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q113120'), ('oName', 'Sliven Province')]
# [('s', 'http://www.wikidata.org/entity/Q25563103'), ('sName', 'Warangal'), ('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q15399'), ('oName', 'Warangal District')]
# [('s', 'http://www.wikidata.org/entity/Q12383937'), ('sName', 'Augas Santas, Allariz'), ('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q1438879'), ('oName', 'Allariz')]
# [('s', 'http://www.wikidata.org/entity/Q2609479'), ('sName', 'Kotel Municipality'), ('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q113120'), ('oName', 'Sliven Province')]
# [('s', 'http://www.wikidata.org/entity/Q11494799'), ('sName', 'Aichi Prefectural Road Route 62'), ('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q1345562'), ('oName', 'Toyoyama')]
# [('s', 'http://www.wikidata.org/entity/Q12358779'), ('sName', 'Aleksandr Podkopajev'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('pName', 'occupation'), ('o', 'http://www.wikidata.org/entity/Q106823762'), ('oName', 'veterinary scientist')]
# [('s', 'http://www.wikidata.org/entity/Q12371070'), ('sName', 'Nikolai Prozorov'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('pName', 'occupation'), ('o', 'http://www.wikidata.org/entity/Q106823762'), ('oName', 'veterinary scientist')]
# [('s', 'http://www.wikidata.org/entity/Q12482400'), ('sName', 'Ella Hilir'), ('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q14162'), ('oName', 'Melawi')]
# [('s', 'http://www.wikidata.org/entity/Q8213279'), ('sName', 'Midai'), ('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q10100'), ('oName', 'Natuna')]
# 100

# %%
# Consider the tennis players born after 1975, return who won more Grand Slams and cut the result to the top-10 (the result set must be a list of triples player IRI, label and #victories).
# Q1426 = Roger Federer
# wdt:P1344 (participant in)
# wdt:P2522 (victory)
#[('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('o', 'http://www.wikidata.org/entity/P569'), ('oName', 'date of birth')]
# 1) getting winners dob 

queryString = """

SELECT DISTINCT ?s ?sName "birthday" ?o ?oName
WHERE {
   # ?s wdt:P3150 ?o.
   # ?s sc:name ?sName.
   # ?o sc:name ?oName.
   
   FILTER (REGEX(?oName,"August 8","i"))
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('s', 'http://www.wikidata.org/entity/Q42012085'), ('sName', 'Hachiman Hikigaya'), ('callret-2', 'birthday'), ('o', 'http://www.wikidata.org/entity/Q2780'), ('oName', 'August 8')]
# [('s', 'http://www.wikidata.org/entity/Q11541253'), ('sName', 'Natsuko Kusuda'), ('callret-2', 'birthday'), ('o', 'http://www.wikidata.org/entity/Q2780'), ('oName', 'August 8')]
# [('s', 'http://www.wikidata.org/entity/Q107038831'), ('sName', 'Hoho Kajino'), ('callret-2', 'birthday'), ('o', 'http://www.wikidata.org/entity/Q2780'), ('oName', 'August 8')]
# [('s', 'http://www.wikidata.org/entity/Q11256924'), ('sName', 'Ryuryū Akari'), ('callret-2', 'birthday'), ('o', 'http://www.wikidata.org/entity/Q2780'), ('oName', 'August 8')]
# [('s', 'http://www.wikidata.org/entity/Q11536787'), ('sName', 'Ryū Katsuragi'), ('callret-2', 'birthday'), ('o', 'http://www.wikidata.org/entity/Q2780'), ('oName', 'August 8')]
# [('s', 'http://www.wikidata.org/entity/Q106478679'), ('sName', 'Tatsuya Nakamura'), ('callret-2', 'birthday'), ('o', 'http://www.wikidata.org/entity/Q2780'), ('oName', 'August 8')]
# [('s', 'http://www.wikidata.org/entity/Q107026111'), ('sName', 'Setsuna Yuki'), ('callret-2', 'birthday'), ('o', 'http://www.wikidata.org/entity/Q2780'), ('oName', 'August 8')]
# [('s', 'http://www.wikidata.org/entity/Q22128446'), ('sName', 'Hachi Hoshikawa'), ('callret-2', 'birthday'), ('o', 'http://www.wikidata.org/entity/Q2780'), ('oName', 'August 8')]
# [('s', 'http://www.wikidata.org/entity/Q16730112'), ('sName', 'Milauna Jackson'), ('callret-2', 'birthday'), ('o', 'http://www.wikidata.org/entity/Q2780'), ('oName', 'August 8')]
# [('s', 'http://www.wikidata.org/entity/Q11483663'), ('sName', 'Rei Hirano'), ('callret-2', 'birthday'), ('o', 'http://www.wikidata.org/entity/Q2780'), ('oName', 'August 8')]
# [('s', 'http://www.wikidata.org/entity/Q54292702'), ('sName', 'Ruri Umino'), ('callret-2', 'birthday'), ('o', 'http://www.wikidata.org/entity/Q2780'), ('oName', 'August 8')]
# [('s', 'http://www.wikidata.org/entity/Q90681265'), ('sName', 'Leif'), ('callret-2', 'birthday'), ('o', 'http://www.wikidata.org/entity/Q2780'), ('oName', 'August 8')]
# [('s', 'http://www.wikidata.org/entity/Q107677643'), ('sName', 'Sarah Berman'), ('callret-2', 'birthday'), ('o', 'http://www.wikidata.org/entity/Q2780'), ('oName', 'August 8')]
# 13

# %%
# Consider the tennis players born after 1975, return who won more Grand Slams and cut the result to the top-10 (the result set must be a list of triples player IRI, label and #victories).
# Q1426 = Roger Federer
# wdt:P1344 (participant in)
# wdt:P2522 (victory)
#[('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('o', 'http://www.wikidata.org/entity/P569'), ('oName', 'date of birth')]
# 1) getting winners dob 

queryString = """

SELECT DISTINCT ?p ?pName ?o ?oName
WHERE {
   wd:Q55539941 ?p ?o.
   # ?p sc:name ?pName.
   # ?o sc:name ?oName.
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P3150'), ('pName', 'birthday'), ('o', 'http://www.wikidata.org/entity/Q2460'), ('oName', 'March 30')]
# [('p', 'http://www.wikidata.org/prop/direct/P106'), ('pName', 'occupation'), ('o', 'http://www.wikidata.org/entity/Q191633'), ('oName', 'mangaka')]
# [('p', 'http://www.wikidata.org/prop/direct/P27'), ('pName', 'country of citizenship'), ('o', 'http://www.wikidata.org/entity/Q17'), ('oName', 'Japan')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('o', 'http://www.wikidata.org/entity/Q5'), ('oName', 'human')]
# [('p', 'http://www.wikidata.org/prop/direct/P21'), ('pName', 'sex or gender'), ('o', 'http://www.wikidata.org/entity/Q6581072'), ('oName', 'female')]
# [('p', 'http://www.wikidata.org/prop/direct/P735'), ('pName', 'given name'), ('o', 'http://www.wikidata.org/entity/Q650689'), ('oName', 'Alice')]
# 6

# %%
# Consider the tennis players born after 1975, return who won more Grand Slams and cut the result to the top-10 (the result set must be a list of triples player IRI, label and #victories).
# Q1426 = Roger Federer
# wdt:P1344 (participant in)
# wdt:P2522 (victory)
#[('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('o', 'http://www.wikidata.org/entity/P569'), ('oName', 'date of birth')]
# 1) getting winners dob 

queryString = """

SELECT DISTINCT ?s ?sName ?p ?pName
WHERE {
   # ?s ?p wd:Q55539941.
   # ?s sc:name ?sName.
   # ?p sc:name ?pName.
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# Empty

# %%
# no use of 'birthday'

# %%
# Consider the tennis players born after 1975, return who won more Grand Slams and cut the result to the top-10 (the result set must be a list of triples player IRI, label and #victories).
# Q1426 = Roger Federer -> August 8, 1981
# wdt:P1344 (participant in)
# wdt:P2522 (victory)
#[('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('o', 'http://www.wikidata.org/entity/P569'), ('oName', 'date of birth')]
# 1) getting winners dob 

queryString = """

SELECT DISTINCT ?s ?sName ?p ?pName ?o ?oName
WHERE {
   # ?s ?p ?o.
   # ?s sc:name ?sName.
   # ?p sc:name ?pName.
   # ?o sc:name ?oName.
   
   # today filter with regex not working
   #FILTER (REGEX(?pName,"birth","i"))
   
   
   #takes to long
   #FILTER (?p not in (wdt:P19, wdt:P3150))
}
LIMIT 5
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('s', 'http://www.wikidata.org/entity/Q95452024'), ('sName', 'Template:Vice Presidents of the Maldives'), ('p', 'http://www.wikidata.org/prop/direct/P1423'), ('pName', 'template has topic'), ('o', 'http://www.wikidata.org/entity/Q10999435'), ('oName', 'Vice President of the Maldives')]
# [('s', 'http://www.wikidata.org/entity/Q25752552'), ('sName', 'Template:2001 in Europe'), ('p', 'http://www.wikidata.org/prop/direct/P1423'), ('pName', 'template has topic'), ('o', 'http://www.wikidata.org/entity/Q17111750'), ('oName', '2001 in Europe')]
# [('s', 'http://www.wikidata.org/entity/Q6675314'), ('sName', 'Template:Alcest'), ('p', 'http://www.wikidata.org/prop/direct/P1423'), ('pName', 'template has topic'), ('o', 'http://www.wikidata.org/entity/Q1517060'), ('oName', 'Alcest')]
# [('s', 'http://www.wikidata.org/entity/Q22785857'), ('sName', 'Template:2006 in Europe'), ('p', 'http://www.wikidata.org/prop/direct/P1423'), ('pName', 'template has topic'), ('o', 'http://www.wikidata.org/entity/Q17111782'), ('oName', '2006 in Europe')]
# [('s', 'http://www.wikidata.org/entity/Q85816744'), ('sName', 'Yodli'), ('p', 'http://www.wikidata.org/prop/direct/P1268'), ('pName', 'represents'), ('o', 'http://www.wikidata.org/entity/Q1053559'), ('oName', '2020 Winter Youth Olympics')]
# 5

# %%
# write your queries

# some how now found [('p', 'http://www.wikidata.org/prop/direct/P569'), ('name', 'date of birth')]
# 1) getting winners dob 


queryString = """
SELECT DISTINCT ?p ?pName ?o ?oName
WHERE {
   # bind something
   wd:Q1426 ?p ?o .
   # get the label
   # ?p sc:name ?pName.
   # ?o sc:name ?oName.
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P2522'), ('pName', 'victory'), ('o', 'http://www.wikidata.org/entity/Q22956224'), ('oName', "2017 Australian Open – Men's Singles")]
# [('p', 'http://www.wikidata.org/prop/direct/P2522'), ('pName', 'victory'), ('o', 'http://www.wikidata.org/entity/Q612597'), ('oName', '2007 Tennis Masters Cup')]
# [('p', 'http://www.wikidata.org/prop/direct/P3342'), ('pName', 'significant person'), ('o', 'http://www.wikidata.org/entity/Q54584'), ('oName', 'Andy Roddick')]
# [('p', 'http://www.wikidata.org/prop/direct/P166'), ('pName', 'award received'), ('o', 'http://www.wikidata.org/entity/Q56509472'), ('oName', 'honorary doctor of the University of Basel')]
# [('p', 'http://www.wikidata.org/prop/direct/P1344'), ('pName', 'participant in'), ('o', 'http://www.wikidata.org/entity/Q589310'), ('oName', "tennis at the 2000 Summer Olympics – men's singles")]
# [('p', 'http://www.wikidata.org/prop/direct/P6758'), ('pName', 'supported sports team'), ('o', 'http://www.wikidata.org/entity/Q189671'), ('oName', 'FC Basel')]
# [('p', 'http://www.wikidata.org/prop/direct/P2522'), ('pName', 'victory'), ('o', 'http://www.wikidata.org/entity/Q782589'), ('oName', "2010 Australian Open – Men's Singles")]
# [('p', 'http://www.wikidata.org/prop/direct/P2522'), ('pName', 'victory'), ('o', 'http://www.wikidata.org/entity/Q782420'), ('oName', "2006 Australian Open – Men's Singles")]
# [('p', 'http://www.wikidata.org/prop/direct/P166'), ('pName', 'award received'), ('o', 'http://www.wikidata.org/entity/Q1061233'), ('oName', "L'Équipe Champion of Champions")]
# [('p', 'http://www.wikidata.org/prop/direct/P106'), ('pName', 'occupation'), ('o', 'http://www.wikidata.org/entity/Q10833314'), ('oName', 'tennis player')]
# [('p', 'http://www.wikidata.org/prop/direct/P741'), ('pName', 'playing hand'), ('o', 'http://www.wikidata.org/entity/Q14420039'), ('oName', 'one-handed backhand')]
# [('p', 'http://www.wikidata.org/prop/direct/P1412'), ('pName', 'languages spoken, written or signed'), ('o', 'http://www.wikidata.org/entity/Q150'), ('oName', 'French')]
# [('p', 'http://www.wikidata.org/prop/direct/P1343'), ('pName', 'described by source'), ('o', 'http://www.wikidata.org/entity/Q17290934'), ('oName', 'Lentapedia')]
# [('p', 'http://www.wikidata.org/prop/direct/P1412'), ('pName', 'languages spoken, written or signed'), ('o', 'http://www.wikidata.org/entity/Q1860'), ('oName', 'English')]
# [('p', 'http://www.wikidata.org/prop/direct/P103'), ('pName', 'native language'), ('o', 'http://www.wikidata.org/entity/Q188'), ('oName', 'German')]
# [('p', 'http://www.wikidata.org/prop/direct/P1412'), ('pName', 'languages spoken, written or signed'), ('o', 'http://www.wikidata.org/entity/Q188'), ('oName', 'German')]
# [('p', 'http://www.wikidata.org/prop/direct/P39'), ('pName', 'position held'), ('o', 'http://www.wikidata.org/entity/Q19969187'), ('oName', 'UNICEF Goodwill Ambassador')]
# [('p', 'http://www.wikidata.org/prop/direct/P552'), ('pName', 'handedness'), ('o', 'http://www.wikidata.org/entity/Q3039938'), ('oName', 'right-handedness')]
# [('p', 'http://www.wikidata.org/prop/direct/P1532'), ('pName', 'country for sport'), ('o', 'http://www.wikidata.org/entity/Q39'), ('oName', 'Switzerland')]
# [('p', 'http://www.wikidata.org/prop/direct/P27'), ('pName', 'country of citizenship'), ('o', 'http://www.wikidata.org/entity/Q39'), ('oName', 'Switzerland')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('o', 'http://www.wikidata.org/entity/Q5'), ('oName', 'human')]
# [('p', 'http://www.wikidata.org/prop/direct/P21'), ('pName', 'sex or gender'), ('o', 'http://www.wikidata.org/entity/Q6581097'), ('oName', 'male')]
# [('p', 'http://www.wikidata.org/prop/direct/P1343'), ('pName', 'described by source'), ('o', 'http://www.wikidata.org/entity/Q67311526'), ('oName', 'Obalky knih.cz')]
# [('p', 'http://www.wikidata.org/prop/direct/P108'), ('pName', 'employer'), ('o', 'http://www.wikidata.org/entity/Q740308'), ('oName', 'UNICEF')]
# [('p', 'http://www.wikidata.org/prop/direct/P19'), ('pName', 'place of birth'), ('o', 'http://www.wikidata.org/entity/Q78'), ('oName', 'Basel')]
# [('p', 'http://www.wikidata.org/prop/direct/P641'), ('pName', 'sport'), ('o', 'http://www.wikidata.org/entity/Q847'), ('oName', 'tennis')]
# [('p', 'http://www.wikidata.org/prop/direct/P1344'), ('pName', 'participant in'), ('o', 'http://www.wikidata.org/entity/Q8544'), ('oName', '2000 Summer Olympics')]
# [('p', 'http://www.wikidata.org/prop/direct/P1344'), ('pName', 'participant in'), ('o', 'http://www.wikidata.org/entity/Q8558'), ('oName', '2004 Summer Olympics')]
# [('p', 'http://www.wikidata.org/prop/direct/P140'), ('pName', 'religion'), ('o', 'http://www.wikidata.org/entity/Q9592'), ('oName', 'Catholic Church')]
# [('p', 'http://www.wikidata.org/prop/direct/P2522'), ('pName', 'victory'), ('o', 'http://www.wikidata.org/entity/Q300024'), ('oName', '2011 ATP World Tour Finals')]
# [('p', 'http://www.wikidata.org/prop/direct/P2416'), ('pName', 'sports discipline competed in'), ('o', 'http://www.wikidata.org/entity/Q18123880'), ('oName', 'tennis singles')]
# [('p', 'http://www.wikidata.org/prop/direct/P2416'), ('pName', 'sports discipline competed in'), ('o', 'http://www.wikidata.org/entity/Q18123885'), ('oName', 'tennis doubles')]
# [('p', 'http://www.wikidata.org/prop/direct/P735'), ('pName', 'given name'), ('o', 'http://www.wikidata.org/entity/Q4925304'), ('oName', 'Roger')]
# [('p', 'http://www.wikidata.org/prop/direct/P166'), ('pName', 'award received'), ('o', 'http://www.wikidata.org/entity/Q338737'), ('oName', 'Swiss Sports Personality of the Year')]
# [('p', 'http://www.wikidata.org/prop/direct/P166'), ('pName', 'award received'), ('o', 'http://www.wikidata.org/entity/Q3494048'), ('oName', 'BBC Overseas Sports Personality of the Year')]
# [('p', 'http://www.wikidata.org/prop/direct/P1344'), ('pName', 'participant in'), ('o', 'http://www.wikidata.org/entity/Q581788'), ('oName', "tennis at the 2012 Summer Olympics – men's singles")]
# [('p', 'http://www.wikidata.org/prop/direct/P2522'), ('pName', 'victory'), ('o', 'http://www.wikidata.org/entity/Q753300'), ('oName', "2012 Wimbledon Championships – Gentlemen's Singles")]
# [('p', 'http://www.wikidata.org/prop/direct/P1344'), ('pName', 'participant in'), ('o', 'http://www.wikidata.org/entity/Q757054'), ('oName', "tennis at the 2008 Summer Olympics – men's doubles")]
# [('p', 'http://www.wikidata.org/prop/direct/P2522'), ('pName', 'victory'), ('o', 'http://www.wikidata.org/entity/Q757054'), ('oName', "tennis at the 2008 Summer Olympics – men's doubles")]
# [('p', 'http://www.wikidata.org/prop/direct/P2522'), ('pName', 'victory'), ('o', 'http://www.wikidata.org/entity/Q1074654'), ('oName', "2006 Wimbledon Championships – Men's Singles")]
# [('p', 'http://www.wikidata.org/prop/direct/P2522'), ('pName', 'victory'), ('o', 'http://www.wikidata.org/entity/Q384929'), ('oName', "2005 Wimbledon Championships – Men's Singles")]
# [('p', 'http://www.wikidata.org/prop/direct/P551'), ('pName', 'residence'), ('o', 'http://www.wikidata.org/entity/Q70036'), ('oName', 'Bottmingen')]
# [('p', 'http://www.wikidata.org/prop/direct/P2522'), ('pName', 'victory'), ('o', 'http://www.wikidata.org/entity/Q14916861'), ('oName', '2014 Davis Cup')]
# [('p', 'http://www.wikidata.org/prop/direct/P741'), ('pName', 'playing hand'), ('o', 'http://www.wikidata.org/entity/Q14419931'), ('oName', 'one-handed forehand')]
# [('p', 'http://www.wikidata.org/prop/direct/P2522'), ('pName', 'victory'), ('o', 'http://www.wikidata.org/entity/Q46993124'), ('oName', "2018 Australian Open – Men's Singles")]
# [('p', 'http://www.wikidata.org/prop/direct/P166'), ('pName', 'award received'), ('o', 'http://www.wikidata.org/entity/Q4896696'), ('oName', 'Best International Athlete ESPY Award')]
# [('p', 'http://www.wikidata.org/prop/direct/P286'), ('pName', 'head coach'), ('o', 'http://www.wikidata.org/entity/Q15649219'), ('oName', 'Severin Lüthi')]
# [('p', 'http://www.wikidata.org/prop/direct/P734'), ('pName', 'family name'), ('o', 'http://www.wikidata.org/entity/Q16869916'), ('oName', 'Federer')]
# [('p', 'http://www.wikidata.org/prop/direct/P286'), ('pName', 'head coach'), ('o', 'http://www.wikidata.org/entity/Q261095'), ('oName', 'Ivan Ljubičić')]
# [('p', 'http://www.wikidata.org/prop/direct/P2522'), ('pName', 'victory'), ('o', 'http://www.wikidata.org/entity/Q964291'), ('oName', '2006 Tennis Masters Cup')]
# [('p', 'http://www.wikidata.org/prop/direct/P2522'), ('pName', 'victory'), ('o', 'http://www.wikidata.org/entity/Q300022'), ('oName', '2010 ATP World Tour Finals')]
# [('p', 'http://www.wikidata.org/prop/direct/P2522'), ('pName', 'victory'), ('o', 'http://www.wikidata.org/entity/Q1048953'), ('oName', "2004 US Open – Men's Singles")]
# [('p', 'http://www.wikidata.org/prop/direct/P2522'), ('pName', 'victory'), ('o', 'http://www.wikidata.org/entity/Q731509'), ('oName', "2005 US Open – Men's Singles")]
# [('p', 'http://www.wikidata.org/prop/direct/P2522'), ('pName', 'victory'), ('o', 'http://www.wikidata.org/entity/Q741573'), ('oName', "2009 French Open – Men's Singles")]
# [('p', 'http://www.wikidata.org/prop/direct/P2522'), ('pName', 'victory'), ('o', 'http://www.wikidata.org/entity/Q912506'), ('oName', "2006 US Open – Men's Singles")]
# [('p', 'http://www.wikidata.org/prop/direct/P2522'), ('pName', 'victory'), ('o', 'http://www.wikidata.org/entity/Q248965'), ('oName', "2004 Wimbledon Championships – Men's Singles")]
# [('p', 'http://www.wikidata.org/prop/direct/P2522'), ('pName', 'victory'), ('o', 'http://www.wikidata.org/entity/Q378627'), ('oName', "2003 Wimbledon Championships – Men's Singles")]
# [('p', 'http://www.wikidata.org/prop/direct/P286'), ('pName', 'head coach'), ('o', 'http://www.wikidata.org/entity/Q1348847'), ('oName', 'José Higueras')]
# [('p', 'http://www.wikidata.org/prop/direct/P2522'), ('pName', 'victory'), ('o', 'http://www.wikidata.org/entity/Q779654'), ('oName', "2004 Australian Open - men's singles")]
# [('p', 'http://www.wikidata.org/prop/direct/P2522'), ('pName', 'victory'), ('o', 'http://www.wikidata.org/entity/Q25344123'), ('oName', "2017 Wimbledon Championships – Men's Singles")]
# [('p', 'http://www.wikidata.org/prop/direct/P22'), ('pName', 'father'), ('o', 'http://www.wikidata.org/entity/Q17291275'), ('oName', 'Robert Federer')]
# [('p', 'http://www.wikidata.org/prop/direct/P25'), ('pName', 'mother'), ('o', 'http://www.wikidata.org/entity/Q17291278'), ('oName', 'Lynette Federer')]
# [('p', 'http://www.wikidata.org/prop/direct/P3373'), ('pName', 'sibling'), ('o', 'http://www.wikidata.org/entity/Q17291284'), ('oName', 'Dziana Federer')]
# [('p', 'http://www.wikidata.org/prop/direct/P40'), ('pName', 'child'), ('o', 'http://www.wikidata.org/entity/Q17291294'), ('oName', 'Myla Federer')]
# [('p', 'http://www.wikidata.org/prop/direct/P40'), ('pName', 'child'), ('o', 'http://www.wikidata.org/entity/Q17291300'), ('oName', 'Charlene Federer')]
# [('p', 'http://www.wikidata.org/prop/direct/P40'), ('pName', 'child'), ('o', 'http://www.wikidata.org/entity/Q17291308'), ('oName', 'Leo Federer')]
# [('p', 'http://www.wikidata.org/prop/direct/P40'), ('pName', 'child'), ('o', 'http://www.wikidata.org/entity/Q17291316'), ('oName', 'Lennart Federer')]
# [('p', 'http://www.wikidata.org/prop/direct/P26'), ('pName', 'spouse'), ('o', 'http://www.wikidata.org/entity/Q233306'), ('oName', 'Mirka Federer')]
# [('p', 'http://www.wikidata.org/prop/direct/P2522'), ('pName', 'victory'), ('o', 'http://www.wikidata.org/entity/Q2478340'), ('oName', '2011 BNP Paribas Masters – singles')]
# [('p', 'http://www.wikidata.org/prop/direct/P2522'), ('pName', 'victory'), ('o', 'http://www.wikidata.org/entity/Q751798'), ('oName', "2009 Wimbledon Championships – Men's Singles")]
# [('p', 'http://www.wikidata.org/prop/direct/P166'), ('pName', 'award received'), ('o', 'http://www.wikidata.org/entity/Q693708'), ('oName', 'ITF World Champions')]
# [('p', 'http://www.wikidata.org/prop/direct/P2522'), ('pName', 'victory'), ('o', 'http://www.wikidata.org/entity/Q782451'), ('oName', "2007 Australian Open – Men's Singles")]
# [('p', 'http://www.wikidata.org/prop/direct/P2522'), ('pName', 'victory'), ('o', 'http://www.wikidata.org/entity/Q912483'), ('oName', "2007 Wimbledon Championships – Men's Singles")]
# [('p', 'http://www.wikidata.org/prop/direct/P2522'), ('pName', 'victory'), ('o', 'http://www.wikidata.org/entity/Q304072'), ('oName', "2008 US Open – Men's Singles")]
# [('p', 'http://www.wikidata.org/prop/direct/P2522'), ('pName', 'victory'), ('o', 'http://www.wikidata.org/entity/Q2031910'), ('oName', '2003 Tennis Masters Cup')]
# [('p', 'http://www.wikidata.org/prop/direct/P2522'), ('pName', 'victory'), ('o', 'http://www.wikidata.org/entity/Q2094307'), ('oName', '2004 Tennis Masters Cup')]
# [('p', 'http://www.wikidata.org/prop/direct/P2522'), ('pName', 'victory'), ('o', 'http://www.wikidata.org/entity/Q836815'), ('oName', "2007 US Open – Men's Singles")]
# [('p', 'http://www.wikidata.org/prop/direct/P910'), ('pName', "topic's main category"), ('o', 'http://www.wikidata.org/entity/Q7257144'), ('oName', 'Category:Roger Federer')]
# [('p', 'http://www.wikidata.org/prop/direct/P286'), ('pName', 'head coach'), ('o', 'http://www.wikidata.org/entity/Q1968483'), ('oName', 'Peter Carter')]
# [('p', 'http://www.wikidata.org/prop/direct/P463'), ('pName', 'member of'), ('o', 'http://www.wikidata.org/entity/Q1675504'), ('oName', 'Swiss Tennis')]
# 80

# %%
# write your queries

# some how now found [('p', 'http://www.wikidata.org/prop/direct/P569'), ('name', 'date of birth')]
# 1) getting winners dob 

queryString = """
SELECT DISTINCT ?p ?pName ?o ?oName
WHERE {
   # bind something
   wd:Q1426 ?p ?o .
   # get the label
   # ?p sc:name ?pName.
   # ?o sc:name ?oName.
   FILTER (?p not in (wdt:P2522, wdt:P166))
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P3342'), ('pName', 'significant person'), ('o', 'http://www.wikidata.org/entity/Q54584'), ('oName', 'Andy Roddick')]
# [('p', 'http://www.wikidata.org/prop/direct/P1344'), ('pName', 'participant in'), ('o', 'http://www.wikidata.org/entity/Q589310'), ('oName', "tennis at the 2000 Summer Olympics – men's singles")]
# [('p', 'http://www.wikidata.org/prop/direct/P6758'), ('pName', 'supported sports team'), ('o', 'http://www.wikidata.org/entity/Q189671'), ('oName', 'FC Basel')]
# [('p', 'http://www.wikidata.org/prop/direct/P106'), ('pName', 'occupation'), ('o', 'http://www.wikidata.org/entity/Q10833314'), ('oName', 'tennis player')]
# [('p', 'http://www.wikidata.org/prop/direct/P741'), ('pName', 'playing hand'), ('o', 'http://www.wikidata.org/entity/Q14420039'), ('oName', 'one-handed backhand')]
# [('p', 'http://www.wikidata.org/prop/direct/P1412'), ('pName', 'languages spoken, written or signed'), ('o', 'http://www.wikidata.org/entity/Q150'), ('oName', 'French')]
# [('p', 'http://www.wikidata.org/prop/direct/P1343'), ('pName', 'described by source'), ('o', 'http://www.wikidata.org/entity/Q17290934'), ('oName', 'Lentapedia')]
# [('p', 'http://www.wikidata.org/prop/direct/P1412'), ('pName', 'languages spoken, written or signed'), ('o', 'http://www.wikidata.org/entity/Q1860'), ('oName', 'English')]
# [('p', 'http://www.wikidata.org/prop/direct/P103'), ('pName', 'native language'), ('o', 'http://www.wikidata.org/entity/Q188'), ('oName', 'German')]
# [('p', 'http://www.wikidata.org/prop/direct/P1412'), ('pName', 'languages spoken, written or signed'), ('o', 'http://www.wikidata.org/entity/Q188'), ('oName', 'German')]
# [('p', 'http://www.wikidata.org/prop/direct/P39'), ('pName', 'position held'), ('o', 'http://www.wikidata.org/entity/Q19969187'), ('oName', 'UNICEF Goodwill Ambassador')]
# [('p', 'http://www.wikidata.org/prop/direct/P552'), ('pName', 'handedness'), ('o', 'http://www.wikidata.org/entity/Q3039938'), ('oName', 'right-handedness')]
# [('p', 'http://www.wikidata.org/prop/direct/P1532'), ('pName', 'country for sport'), ('o', 'http://www.wikidata.org/entity/Q39'), ('oName', 'Switzerland')]
# [('p', 'http://www.wikidata.org/prop/direct/P27'), ('pName', 'country of citizenship'), ('o', 'http://www.wikidata.org/entity/Q39'), ('oName', 'Switzerland')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('o', 'http://www.wikidata.org/entity/Q5'), ('oName', 'human')]
# [('p', 'http://www.wikidata.org/prop/direct/P21'), ('pName', 'sex or gender'), ('o', 'http://www.wikidata.org/entity/Q6581097'), ('oName', 'male')]
# [('p', 'http://www.wikidata.org/prop/direct/P1343'), ('pName', 'described by source'), ('o', 'http://www.wikidata.org/entity/Q67311526'), ('oName', 'Obalky knih.cz')]
# [('p', 'http://www.wikidata.org/prop/direct/P108'), ('pName', 'employer'), ('o', 'http://www.wikidata.org/entity/Q740308'), ('oName', 'UNICEF')]
# [('p', 'http://www.wikidata.org/prop/direct/P19'), ('pName', 'place of birth'), ('o', 'http://www.wikidata.org/entity/Q78'), ('oName', 'Basel')]
# [('p', 'http://www.wikidata.org/prop/direct/P641'), ('pName', 'sport'), ('o', 'http://www.wikidata.org/entity/Q847'), ('oName', 'tennis')]
# [('p', 'http://www.wikidata.org/prop/direct/P1344'), ('pName', 'participant in'), ('o', 'http://www.wikidata.org/entity/Q8544'), ('oName', '2000 Summer Olympics')]
# [('p', 'http://www.wikidata.org/prop/direct/P1344'), ('pName', 'participant in'), ('o', 'http://www.wikidata.org/entity/Q8558'), ('oName', '2004 Summer Olympics')]
# [('p', 'http://www.wikidata.org/prop/direct/P140'), ('pName', 'religion'), ('o', 'http://www.wikidata.org/entity/Q9592'), ('oName', 'Catholic Church')]
# [('p', 'http://www.wikidata.org/prop/direct/P2416'), ('pName', 'sports discipline competed in'), ('o', 'http://www.wikidata.org/entity/Q18123880'), ('oName', 'tennis singles')]
# [('p', 'http://www.wikidata.org/prop/direct/P2416'), ('pName', 'sports discipline competed in'), ('o', 'http://www.wikidata.org/entity/Q18123885'), ('oName', 'tennis doubles')]
# [('p', 'http://www.wikidata.org/prop/direct/P735'), ('pName', 'given name'), ('o', 'http://www.wikidata.org/entity/Q4925304'), ('oName', 'Roger')]
# [('p', 'http://www.wikidata.org/prop/direct/P1344'), ('pName', 'participant in'), ('o', 'http://www.wikidata.org/entity/Q581788'), ('oName', "tennis at the 2012 Summer Olympics – men's singles")]
# [('p', 'http://www.wikidata.org/prop/direct/P1344'), ('pName', 'participant in'), ('o', 'http://www.wikidata.org/entity/Q757054'), ('oName', "tennis at the 2008 Summer Olympics – men's doubles")]
# [('p', 'http://www.wikidata.org/prop/direct/P551'), ('pName', 'residence'), ('o', 'http://www.wikidata.org/entity/Q70036'), ('oName', 'Bottmingen')]
# [('p', 'http://www.wikidata.org/prop/direct/P741'), ('pName', 'playing hand'), ('o', 'http://www.wikidata.org/entity/Q14419931'), ('oName', 'one-handed forehand')]
# [('p', 'http://www.wikidata.org/prop/direct/P286'), ('pName', 'head coach'), ('o', 'http://www.wikidata.org/entity/Q15649219'), ('oName', 'Severin Lüthi')]
# [('p', 'http://www.wikidata.org/prop/direct/P734'), ('pName', 'family name'), ('o', 'http://www.wikidata.org/entity/Q16869916'), ('oName', 'Federer')]
# [('p', 'http://www.wikidata.org/prop/direct/P286'), ('pName', 'head coach'), ('o', 'http://www.wikidata.org/entity/Q261095'), ('oName', 'Ivan Ljubičić')]
# [('p', 'http://www.wikidata.org/prop/direct/P286'), ('pName', 'head coach'), ('o', 'http://www.wikidata.org/entity/Q1348847'), ('oName', 'José Higueras')]
# [('p', 'http://www.wikidata.org/prop/direct/P22'), ('pName', 'father'), ('o', 'http://www.wikidata.org/entity/Q17291275'), ('oName', 'Robert Federer')]
# [('p', 'http://www.wikidata.org/prop/direct/P25'), ('pName', 'mother'), ('o', 'http://www.wikidata.org/entity/Q17291278'), ('oName', 'Lynette Federer')]
# [('p', 'http://www.wikidata.org/prop/direct/P3373'), ('pName', 'sibling'), ('o', 'http://www.wikidata.org/entity/Q17291284'), ('oName', 'Dziana Federer')]
# [('p', 'http://www.wikidata.org/prop/direct/P40'), ('pName', 'child'), ('o', 'http://www.wikidata.org/entity/Q17291294'), ('oName', 'Myla Federer')]
# [('p', 'http://www.wikidata.org/prop/direct/P40'), ('pName', 'child'), ('o', 'http://www.wikidata.org/entity/Q17291300'), ('oName', 'Charlene Federer')]
# [('p', 'http://www.wikidata.org/prop/direct/P40'), ('pName', 'child'), ('o', 'http://www.wikidata.org/entity/Q17291308'), ('oName', 'Leo Federer')]
# [('p', 'http://www.wikidata.org/prop/direct/P40'), ('pName', 'child'), ('o', 'http://www.wikidata.org/entity/Q17291316'), ('oName', 'Lennart Federer')]
# [('p', 'http://www.wikidata.org/prop/direct/P26'), ('pName', 'spouse'), ('o', 'http://www.wikidata.org/entity/Q233306'), ('oName', 'Mirka Federer')]
# [('p', 'http://www.wikidata.org/prop/direct/P910'), ('pName', "topic's main category"), ('o', 'http://www.wikidata.org/entity/Q7257144'), ('oName', 'Category:Roger Federer')]
# [('p', 'http://www.wikidata.org/prop/direct/P286'), ('pName', 'head coach'), ('o', 'http://www.wikidata.org/entity/Q1968483'), ('oName', 'Peter Carter')]
# [('p', 'http://www.wikidata.org/prop/direct/P463'), ('pName', 'member of'), ('o', 'http://www.wikidata.org/entity/Q1675504'), ('oName', 'Swiss Tennis')]
# 45

# %%
# write your queries

# some how now found [('p', 'http://www.wikidata.org/prop/direct/P569'), ('name', 'date of birth')]
# 1) getting winners dob 

queryString = """
SELECT DISTINCT ?o ?oName
WHERE {
   wd:Q1426 wdt:P569 ?o .
   # ?o sc:name ?oName.
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# Empty

# %%
# write your queries

# some how now found [('p', 'http://www.wikidata.org/prop/direct/P569'), ('name', 'date of birth')]
# 1) getting winners dob 

queryString = """
SELECT DISTINCT ?p ?pName
WHERE {
   wd:Q1426 ?p ?o .
   # ?p sc:name ?pName.
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P1006'), ('pName', 'Nationale Thesaurus voor Auteurs ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P103'), ('pName', 'native language')]
# [('p', 'http://www.wikidata.org/prop/direct/P106'), ('pName', 'occupation')]
# [('p', 'http://www.wikidata.org/prop/direct/P108'), ('pName', 'employer')]
# [('p', 'http://www.wikidata.org/prop/direct/P1263'), ('pName', 'NNDB people ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1280'), ('pName', 'CONOR.SI ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1284'), ('pName', 'Munzinger person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1285'), ('pName', 'Munzinger Sport number')]
# [('p', 'http://www.wikidata.org/prop/direct/P1296'), ('pName', 'Gran Enciclopèdia Catalana ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1343'), ('pName', 'described by source')]
# [('p', 'http://www.wikidata.org/prop/direct/P1344'), ('pName', 'participant in')]
# [('p', 'http://www.wikidata.org/prop/direct/P1352'), ('pName', 'ranking')]
# [('p', 'http://www.wikidata.org/prop/direct/P140'), ('pName', 'religion')]
# [('p', 'http://www.wikidata.org/prop/direct/P1412'), ('pName', 'languages spoken, written or signed')]
# [('p', 'http://www.wikidata.org/prop/direct/P1417'), ('pName', 'Encyclopædia Britannica Online ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1447'), ('pName', 'Sports-Reference.com Olympic athlete ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1532'), ('pName', 'country for sport')]
# [('p', 'http://www.wikidata.org/prop/direct/P166'), ('pName', 'award received')]
# [('p', 'http://www.wikidata.org/prop/direct/P1695'), ('pName', 'NLP ID (unique)')]
# [('p', 'http://www.wikidata.org/prop/direct/P1741'), ('pName', 'GTAA ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P18'), ('pName', 'image')]
# [('p', 'http://www.wikidata.org/prop/direct/P19'), ('pName', 'place of birth')]
# [('p', 'http://www.wikidata.org/prop/direct/P2002'), ('pName', 'Twitter username')]
# [('p', 'http://www.wikidata.org/prop/direct/P2003'), ('pName', 'Instagram username')]
# [('p', 'http://www.wikidata.org/prop/direct/P2013'), ('pName', 'Facebook ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2019'), ('pName', 'AllMovie person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2031'), ('pName', 'work period (start)')]
# [('p', 'http://www.wikidata.org/prop/direct/P2048'), ('pName', 'height')]
# [('p', 'http://www.wikidata.org/prop/direct/P2067'), ('pName', 'mass')]
# [('p', 'http://www.wikidata.org/prop/direct/P21'), ('pName', 'sex or gender')]
# [('p', 'http://www.wikidata.org/prop/direct/P2121'), ('pName', 'prize money')]
# [('p', 'http://www.wikidata.org/prop/direct/P213'), ('pName', 'ISNI')]
# [('p', 'http://www.wikidata.org/prop/direct/P214'), ('pName', 'VIAF ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2163'), ('pName', 'FAST ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P22'), ('pName', 'father')]
# [('p', 'http://www.wikidata.org/prop/direct/P2218'), ('pName', 'net worth')]
# [('p', 'http://www.wikidata.org/prop/direct/P227'), ('pName', 'GND ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2416'), ('pName', 'sports discipline competed in')]
# [('p', 'http://www.wikidata.org/prop/direct/P244'), ('pName', 'Library of Congress authority ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P25'), ('pName', 'mother')]
# [('p', 'http://www.wikidata.org/prop/direct/P2522'), ('pName', 'victory')]
# [('p', 'http://www.wikidata.org/prop/direct/P26'), ('pName', 'spouse')]
# [('p', 'http://www.wikidata.org/prop/direct/P2604'), ('pName', 'Kinopoisk person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2605'), ('pName', 'ČSFD person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P268'), ('pName', 'Bibliothèque nationale de France ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P269'), ('pName', 'IdRef ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P27'), ('pName', 'country of citizenship')]
# [('p', 'http://www.wikidata.org/prop/direct/P286'), ('pName', 'head coach')]
# [('p', 'http://www.wikidata.org/prop/direct/P2924'), ('pName', 'Great Russian Encyclopedia Online ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('p', 'http://www.wikidata.org/prop/direct/P3171'), ('pName', 'Olympic.org athlete ID (archived version)')]
# [('p', 'http://www.wikidata.org/prop/direct/P3219'), ('pName', 'Encyclopædia Universalis ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3221'), ('pName', 'New York Times topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3222'), ('pName', 'NE.se ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3342'), ('pName', 'significant person')]
# [('p', 'http://www.wikidata.org/prop/direct/P3373'), ('pName', 'sibling')]
# [('p', 'http://www.wikidata.org/prop/direct/P3388'), ('pName', 'LittleSis people ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3417'), ('pName', 'Quora topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3427'), ('pName', 'AS.com athlete ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P345'), ('pName', 'IMDb ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3509'), ('pName', 'Dagens Nyheter topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3553'), ('pName', 'Zhihu topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3630'), ('pName', 'Babelio author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P373'), ('pName', 'Commons category')]
# [('p', 'http://www.wikidata.org/prop/direct/P3846'), ('pName', 'DBC author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P39'), ('pName', 'position held')]
# [('p', 'http://www.wikidata.org/prop/direct/P40'), ('pName', 'child')]
# [('p', 'http://www.wikidata.org/prop/direct/P4342'), ('pName', 'Store norske leksikon ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P4544'), ('pName', 'Tennis Temple player ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P463'), ('pName', 'member of')]
# [('p', 'http://www.wikidata.org/prop/direct/P4666'), ('pName', 'CineMagia person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P4789'), ('pName', "Who's Who UK ID")]
# [('p', 'http://www.wikidata.org/prop/direct/P4985'), ('pName', 'TMDb person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5019'), ('pName', 'Brockhaus Enzyklopädie online ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5034'), ('pName', 'National Library of Korea ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5247'), ('pName', 'Giant Bomb ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5337'), ('pName', 'Google News topics ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5361'), ('pName', 'BNB person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5421'), ('pName', 'Trading Card Database person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P551'), ('pName', 'residence')]
# [('p', 'http://www.wikidata.org/prop/direct/P552'), ('pName', 'handedness')]
# [('p', 'http://www.wikidata.org/prop/direct/P555'), ('pName', 'doubles record')]
# [('p', 'http://www.wikidata.org/prop/direct/P5617'), ('pName', 'Evene ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P564'), ('pName', 'singles record')]
# [('p', 'http://www.wikidata.org/prop/direct/P569'), ('pName', 'date of birth')]
# [('p', 'http://www.wikidata.org/prop/direct/P5815'), ('pName', 'Olympics.com athlete ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P599'), ('pName', 'ITF player ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6262'), ('pName', 'Fandom article ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6327'), ('pName', 'Goodreads character ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P641'), ('pName', 'sport')]
# [('p', 'http://www.wikidata.org/prop/direct/P646'), ('pName', 'Freebase ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6553'), ('pName', 'personal pronoun')]
# [('p', 'http://www.wikidata.org/prop/direct/P6573'), ('pName', 'Klexikon article ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6656'), ('pName', 'BHCL ID (former scheme)')]
# [('p', 'http://www.wikidata.org/prop/direct/P6683'), ('pName', 'Alexander Turnbull Library ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6868'), ('pName', 'Hoopla artist ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P691'), ('pName', 'NKCR AUT ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7293'), ('pName', 'PLWABN ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P734'), ('pName', 'family name')]
# [('p', 'http://www.wikidata.org/prop/direct/P735'), ('pName', 'given name')]
# 100

# %%
# write your queries

# some how now found [('p', 'http://www.wikidata.org/prop/direct/P569'), ('name', 'date of birth')]
# 1) getting winners dob 

queryString = """
SELECT DISTINCT ?p ?pName
WHERE {
   wd:Q1426 ?p ?o .
   # ?p sc:name ?pName.
   
   FILTER (?p in (wdt:P569))
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P569'), ('pName', 'date of birth')]
# 1

# %%
# write your queries

# some how now found [('p', 'http://www.wikidata.org/prop/direct/P569'), ('name', 'date of birth')]
# 1) getting winners dob 

queryString = """
SELECT DISTINCT ?o ?name
WHERE {
   wd:Q1426 ?p ?o .
   # ?o sc:name ?name.
   
   FILTER (?p in (wdt:P569))
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# Empty

# %%
# write your queries

# some how now found [('p', 'http://www.wikidata.org/prop/direct/P569'), ('name', 'date of birth')]
# 1) getting winners dob 

queryString = """
SELECT ?o ?name
WHERE {
   wd:Q1426 ?p ?o .
   # ?o sc:name ?name.
   
   FILTER (?p in (wdt:P569))
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# Empty

# %% [markdown]
# ##### FINALLYYYYYYY AFTER 300 QUERIES

# %%
# write your queries

# some how now found [('p', 'http://www.wikidata.org/prop/direct/P569'), ('name', 'date of birth')]
# 1) getting winners dob 

queryString = """
SELECT ?o
WHERE {
   wd:Q1426 ?p ?o .   
   FILTER (?p in (wdt:P569))
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('o', '1981-08-08T00:00:00Z')]
# 1

# %%
# write your queries

# Consider the tennis players born after 1975, return who won more Grand Slams and cut the result to the top-10 (the result set must be a list of triples player IRI, label and #victories).

# from task3 [('obj', 'http://www.wikidata.org/entity/Q41520'), ('objName', 'Wimbledon Championships')]
# <---P31 instance of -- Q30085309 '2018 Wimbledon Championships'
# --P527 ('has part')--> Q30098268 "2018 Wimbledon Championships – Women's Singles" --> P1346 ('winner') -->

# 1) getting all winner of yearly Wimbledon Tournament
queryString = """

SELECT DISTINCT ?yearlyWimbledonTournament ?yearlyWimbledonTournamentName ?subTournament ?subTournamentName ?winner ?winnerName
WHERE {
   # BACKWARD DISCOVERY
   # ?yearlyWimbledonTournament wdt:P31 wd:Q41520.
   # ?yearlyWimbledonTournament wdt:P527 ?subTournament.
   # ?subTournament wdt:P1346 ?winner.
   
   # get the label 
   # ?yearlyWimbledonTournament sc:name ?yearlyWimbledonTournamentName .
   # ?subTournament sc:name ?subTournamentName.
   # ?winner sc:name ?winnerName.
}
ORDER BY ASC (?subTournamentName)
LIMIT 20

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q1934049'), ('yearlyWimbledonTournamentName', '1877 Wimbledon Championship'), ('subTournament', 'http://www.wikidata.org/entity/Q1354887'), ('subTournamentName', '1877 Wimbledon Championship – singles'), ('winner', 'http://www.wikidata.org/entity/Q469884'), ('winnerName', 'Spencer Gore')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q1253069'), ('yearlyWimbledonTournamentName', '1878 Wimbledon Championships'), ('subTournament', 'http://www.wikidata.org/entity/Q1356483'), ('subTournamentName', '1878 Wimbledon Championship – singles'), ('winner', 'http://www.wikidata.org/entity/Q469922'), ('winnerName', 'Frank Hadow')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q726549'), ('yearlyWimbledonTournamentName', '1879 Wimbledon Championship'), ('subTournament', 'http://www.wikidata.org/entity/Q1357074'), ('subTournamentName', '1879 Wimbledon Championship – singles'), ('winner', 'http://www.wikidata.org/entity/Q538191'), ('winnerName', 'John Hartley')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q2296326'), ('yearlyWimbledonTournamentName', '1880 Wimbledon Championship'), ('subTournament', 'http://www.wikidata.org/entity/Q1355471'), ('subTournamentName', '1880 Wimbledon Championship – singles'), ('winner', 'http://www.wikidata.org/entity/Q538191'), ('winnerName', 'John Hartley')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q2296335'), ('yearlyWimbledonTournamentName', '1881 Wimbledon Championship'), ('subTournament', 'http://www.wikidata.org/entity/Q1356657'), ('subTournamentName', '1881 Wimbledon Championship – singles'), ('winner', 'http://www.wikidata.org/entity/Q365139'), ('winnerName', 'William Renshaw')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q2297185'), ('yearlyWimbledonTournamentName', '1882 Wimbledon Championship'), ('subTournament', 'http://www.wikidata.org/entity/Q1356370'), ('subTournamentName', '1882 Wimbledon Championship – singles'), ('winner', 'http://www.wikidata.org/entity/Q365139'), ('winnerName', 'William Renshaw')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q522860'), ('yearlyWimbledonTournamentName', '1883 Wimbledon Championship'), ('subTournament', 'http://www.wikidata.org/entity/Q1273149'), ('subTournamentName', '1883 Wimbledon Championship – singles'), ('winner', 'http://www.wikidata.org/entity/Q365139'), ('winnerName', 'William Renshaw')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q1803935'), ('yearlyWimbledonTournamentName', '1884 Wimbledon Championships'), ('subTournament', 'http://www.wikidata.org/entity/Q1235387'), ('subTournamentName', "1884 Wimbledon Championships – Gentlemen's Singles"), ('winner', 'http://www.wikidata.org/entity/Q365139'), ('winnerName', 'William Renshaw')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q1803935'), ('yearlyWimbledonTournamentName', '1884 Wimbledon Championships'), ('subTournament', 'http://www.wikidata.org/entity/Q1567939'), ('subTournamentName', "1884 Wimbledon Championships – Ladies' Singles"), ('winner', 'http://www.wikidata.org/entity/Q262027'), ('winnerName', 'Maud Watson')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q1326511'), ('yearlyWimbledonTournamentName', '1885 Wimbledon Championships'), ('subTournament', 'http://www.wikidata.org/entity/Q1356316'), ('subTournamentName', "1885 Wimbledon Championships – Gentlemen's Singles"), ('winner', 'http://www.wikidata.org/entity/Q365139'), ('winnerName', 'William Renshaw')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q1326511'), ('yearlyWimbledonTournamentName', '1885 Wimbledon Championships'), ('subTournament', 'http://www.wikidata.org/entity/Q729656'), ('subTournamentName', "1885 Wimbledon Championships – Ladies' Singles"), ('winner', 'http://www.wikidata.org/entity/Q262027'), ('winnerName', 'Maud Watson')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q47220'), ('yearlyWimbledonTournamentName', '1886 Wimbledon Championships'), ('subTournament', 'http://www.wikidata.org/entity/Q1797148'), ('subTournamentName', "1886 Wimbledon Championships – Gentlemen's Doubles"), ('winner', 'http://www.wikidata.org/entity/Q505764'), ('winnerName', 'Ernest Renshaw')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q47220'), ('yearlyWimbledonTournamentName', '1886 Wimbledon Championships'), ('subTournament', 'http://www.wikidata.org/entity/Q1356364'), ('subTournamentName', "1886 Wimbledon Championships – Gentlemen's Singles"), ('winner', 'http://www.wikidata.org/entity/Q365139'), ('winnerName', 'William Renshaw')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q47220'), ('yearlyWimbledonTournamentName', '1886 Wimbledon Championships'), ('subTournament', 'http://www.wikidata.org/entity/Q1560096'), ('subTournamentName', "1886 Wimbledon Championships – Ladies' Singles"), ('winner', 'http://www.wikidata.org/entity/Q273468'), ('winnerName', 'Blanche Bingley')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q2119702'), ('yearlyWimbledonTournamentName', '1910 Wimbledon Championships'), ('subTournament', 'http://www.wikidata.org/entity/Q2582773'), ('subTournamentName', "1910 Wimbledon Championships – Men's Doubles"), ('winner', 'http://www.wikidata.org/entity/Q710611'), ('winnerName', 'Major Ritchie')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q2119702'), ('yearlyWimbledonTournamentName', '1910 Wimbledon Championships'), ('subTournament', 'http://www.wikidata.org/entity/Q476944'), ('subTournamentName', "1910 Wimbledon Championships – Men's Singles"), ('winner', 'http://www.wikidata.org/entity/Q505788'), ('winnerName', 'Anthony Wilding')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q2119702'), ('yearlyWimbledonTournamentName', '1910 Wimbledon Championships'), ('subTournament', 'http://www.wikidata.org/entity/Q2483970'), ('subTournamentName', "1910 Wimbledon Championships – Women's Singles"), ('winner', 'http://www.wikidata.org/entity/Q53369'), ('winnerName', 'Dorothea Douglass')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q501879'), ('yearlyWimbledonTournamentName', '1946 Wimbledon Championships'), ('subTournament', 'http://www.wikidata.org/entity/Q501902'), ('subTournamentName', "1946 Wimbledon Championships – Men's Singles"), ('winner', 'http://www.wikidata.org/entity/Q957935'), ('winnerName', 'Yvon Petra')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q501879'), ('yearlyWimbledonTournamentName', '1946 Wimbledon Championships'), ('subTournament', 'http://www.wikidata.org/entity/Q501871'), ('subTournamentName', "1946 Wimbledon Championships – Women's Singles"), ('winner', 'http://www.wikidata.org/entity/Q53331'), ('winnerName', 'Pauline Betz')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q501884'), ('yearlyWimbledonTournamentName', '1947 Wimbledon Championships'), ('subTournament', 'http://www.wikidata.org/entity/Q501895'), ('subTournamentName', "1947 Wimbledon Championships – Men's Singles"), ('winner', 'http://www.wikidata.org/entity/Q54529'), ('winnerName', 'Jack Kramer')]
# 20

# %%
# write your queries

# Consider the tennis players born after 1975, return who won more Grand Slams and cut the result to the top-10 (the result set must be a list of triples player IRI, label and #victories).

# from task3 [('obj', 'http://www.wikidata.org/entity/Q41520'), ('objName', 'Wimbledon Championships')]
# <---P31 instance of -- Q30085309 '2018 Wimbledon Championships'
# --P527 ('has part')--> Q30098268 "2018 Wimbledon Championships – Women's Singles" --> P1346 ('winner') -->

# 1 - getting all winner of yearly Wimbledon Tournament
# 2 - retrieving their dob to select only those who was born after 1975
queryString = """

SELECT DISTINCT ?yearlyWimbledonTournament ?yearlyWimbledonTournamentName ?subTournament ?subTournamentName ?winner ?winnerName ?dob
WHERE {
   # BACKWARD DISCOVERY
   # ?yearlyWimbledonTournament ?p wd:Q41520.
   # ?yearlyWimbledonTournament wdt:P527 ?subTournament.
   # ?subTournament wdt:P1346 ?winner.
   
   # get the label 
   # ?yearlyWimbledonTournament sc:name ?yearlyWimbledonTournamentName .
   # ?subTournament sc:name ?subTournamentName.
   # ?winner sc:name ?winnerName.
   # ?winner wdt:P569 ?dob
}
ORDER BY ASC (?dob)
LIMIT 20

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q2296326'), ('yearlyWimbledonTournamentName', '1880 Wimbledon Championship'), ('subTournament', 'http://www.wikidata.org/entity/Q1355471'), ('subTournamentName', '1880 Wimbledon Championship – singles'), ('winner', 'http://www.wikidata.org/entity/Q538191'), ('winnerName', 'John Hartley'), ('dob', '1849-01-09T00:00:00Z')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q726549'), ('yearlyWimbledonTournamentName', '1879 Wimbledon Championship'), ('subTournament', 'http://www.wikidata.org/entity/Q1357074'), ('subTournamentName', '1879 Wimbledon Championship – singles'), ('winner', 'http://www.wikidata.org/entity/Q538191'), ('winnerName', 'John Hartley'), ('dob', '1849-01-09T00:00:00Z')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q1934049'), ('yearlyWimbledonTournamentName', '1877 Wimbledon Championship'), ('subTournament', 'http://www.wikidata.org/entity/Q1354887'), ('subTournamentName', '1877 Wimbledon Championship – singles'), ('winner', 'http://www.wikidata.org/entity/Q469884'), ('winnerName', 'Spencer Gore'), ('dob', '1850-03-10T00:00:00Z')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q1253069'), ('yearlyWimbledonTournamentName', '1878 Wimbledon Championships'), ('subTournament', 'http://www.wikidata.org/entity/Q1356483'), ('subTournamentName', '1878 Wimbledon Championship – singles'), ('winner', 'http://www.wikidata.org/entity/Q469922'), ('winnerName', 'Frank Hadow'), ('dob', '1855-01-24T00:00:00Z')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q2297185'), ('yearlyWimbledonTournamentName', '1882 Wimbledon Championship'), ('subTournament', 'http://www.wikidata.org/entity/Q1356370'), ('subTournamentName', '1882 Wimbledon Championship – singles'), ('winner', 'http://www.wikidata.org/entity/Q365139'), ('winnerName', 'William Renshaw'), ('dob', '1861-01-03T00:00:00Z')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q47220'), ('yearlyWimbledonTournamentName', '1886 Wimbledon Championships'), ('subTournament', 'http://www.wikidata.org/entity/Q1356364'), ('subTournamentName', "1886 Wimbledon Championships – Gentlemen's Singles"), ('winner', 'http://www.wikidata.org/entity/Q365139'), ('winnerName', 'William Renshaw'), ('dob', '1861-01-03T00:00:00Z')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q1803935'), ('yearlyWimbledonTournamentName', '1884 Wimbledon Championships'), ('subTournament', 'http://www.wikidata.org/entity/Q1235387'), ('subTournamentName', "1884 Wimbledon Championships – Gentlemen's Singles"), ('winner', 'http://www.wikidata.org/entity/Q365139'), ('winnerName', 'William Renshaw'), ('dob', '1861-01-03T00:00:00Z')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q1326511'), ('yearlyWimbledonTournamentName', '1885 Wimbledon Championships'), ('subTournament', 'http://www.wikidata.org/entity/Q1356316'), ('subTournamentName', "1885 Wimbledon Championships – Gentlemen's Singles"), ('winner', 'http://www.wikidata.org/entity/Q365139'), ('winnerName', 'William Renshaw'), ('dob', '1861-01-03T00:00:00Z')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q522860'), ('yearlyWimbledonTournamentName', '1883 Wimbledon Championship'), ('subTournament', 'http://www.wikidata.org/entity/Q1273149'), ('subTournamentName', '1883 Wimbledon Championship – singles'), ('winner', 'http://www.wikidata.org/entity/Q365139'), ('winnerName', 'William Renshaw'), ('dob', '1861-01-03T00:00:00Z')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q2296335'), ('yearlyWimbledonTournamentName', '1881 Wimbledon Championship'), ('subTournament', 'http://www.wikidata.org/entity/Q1356657'), ('subTournamentName', '1881 Wimbledon Championship – singles'), ('winner', 'http://www.wikidata.org/entity/Q365139'), ('winnerName', 'William Renshaw'), ('dob', '1861-01-03T00:00:00Z')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q47220'), ('yearlyWimbledonTournamentName', '1886 Wimbledon Championships'), ('subTournament', 'http://www.wikidata.org/entity/Q1797148'), ('subTournamentName', "1886 Wimbledon Championships – Gentlemen's Doubles"), ('winner', 'http://www.wikidata.org/entity/Q505764'), ('winnerName', 'Ernest Renshaw'), ('dob', '1861-01-03T00:00:00Z')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q47220'), ('yearlyWimbledonTournamentName', '1886 Wimbledon Championships'), ('subTournament', 'http://www.wikidata.org/entity/Q1560096'), ('subTournamentName', "1886 Wimbledon Championships – Ladies' Singles"), ('winner', 'http://www.wikidata.org/entity/Q273468'), ('winnerName', 'Blanche Bingley'), ('dob', '1863-11-03T00:00:00Z')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q1803935'), ('yearlyWimbledonTournamentName', '1884 Wimbledon Championships'), ('subTournament', 'http://www.wikidata.org/entity/Q1567939'), ('subTournamentName', "1884 Wimbledon Championships – Ladies' Singles"), ('winner', 'http://www.wikidata.org/entity/Q262027'), ('winnerName', 'Maud Watson'), ('dob', '1864-10-09T00:00:00Z')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q1326511'), ('yearlyWimbledonTournamentName', '1885 Wimbledon Championships'), ('subTournament', 'http://www.wikidata.org/entity/Q729656'), ('subTournamentName', "1885 Wimbledon Championships – Ladies' Singles"), ('winner', 'http://www.wikidata.org/entity/Q262027'), ('winnerName', 'Maud Watson'), ('dob', '1864-10-09T00:00:00Z')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q2119702'), ('yearlyWimbledonTournamentName', '1910 Wimbledon Championships'), ('subTournament', 'http://www.wikidata.org/entity/Q2582773'), ('subTournamentName', "1910 Wimbledon Championships – Men's Doubles"), ('winner', 'http://www.wikidata.org/entity/Q710611'), ('winnerName', 'Major Ritchie'), ('dob', '1870-10-18T00:00:00Z')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q2119702'), ('yearlyWimbledonTournamentName', '1910 Wimbledon Championships'), ('subTournament', 'http://www.wikidata.org/entity/Q2483970'), ('subTournamentName', "1910 Wimbledon Championships – Women's Singles"), ('winner', 'http://www.wikidata.org/entity/Q53369'), ('winnerName', 'Dorothea Douglass'), ('dob', '1878-09-03T00:00:00Z')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q2119702'), ('yearlyWimbledonTournamentName', '1910 Wimbledon Championships'), ('subTournament', 'http://www.wikidata.org/entity/Q476944'), ('subTournamentName', "1910 Wimbledon Championships – Men's Singles"), ('winner', 'http://www.wikidata.org/entity/Q505788'), ('winnerName', 'Anthony Wilding'), ('dob', '1883-10-31T00:00:00Z')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q657950'), ('yearlyWimbledonTournamentName', '1957 Wimbledon Championships'), ('subTournament', 'http://www.wikidata.org/entity/Q1275316'), ('subTournamentName', "1957 Wimbledon Championships – Men's Doubles"), ('winner', 'http://www.wikidata.org/entity/Q54544'), ('winnerName', 'Gardnar Mulloy'), ('dob', '1913-11-22T00:00:00Z')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q501879'), ('yearlyWimbledonTournamentName', '1946 Wimbledon Championships'), ('subTournament', 'http://www.wikidata.org/entity/Q501902'), ('subTournamentName', "1946 Wimbledon Championships – Men's Singles"), ('winner', 'http://www.wikidata.org/entity/Q957935'), ('winnerName', 'Yvon Petra'), ('dob', '1916-03-08T00:00:00Z')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q501884'), ('yearlyWimbledonTournamentName', '1947 Wimbledon Championships'), ('subTournament', 'http://www.wikidata.org/entity/Q501889'), ('subTournamentName', "1947 Wimbledon Championships – Women's Singles"), ('winner', 'http://www.wikidata.org/entity/Q53411'), ('winnerName', 'Margaret Osborne duPont'), ('dob', '1918-03-04T00:00:00Z')]
# 20

# %%
# write your queries

# Consider the tennis players born after 1975, return who won more Grand Slams and cut the result to the top-10 (the result set must be a list of triples player IRI, label and #victories).

# from task3 [('obj', 'http://www.wikidata.org/entity/Q41520'), ('objName', 'Wimbledon Championships')]
# <---P31 instance of -- Q30085309 '2018 Wimbledon Championships'
# --P527 ('has part')--> Q30098268 "2018 Wimbledon Championships – Women's Singles" --> P1346 ('winner') -->

# 1 - getting all winner of yearly Wimbledon Tournament
# 2 - select only those who was born after 1975
queryString = """

PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
SELECT DISTINCT ?yearlyWimbledonTournament ?yearlyWimbledonTournamentName ?subTournament ?subTournamentName ?winner ?winnerName ?dob
WHERE {
   # BACKWARD DISCOVERY
   # ?yearlyWimbledonTournament ?p wd:Q41520.
   # ?yearlyWimbledonTournament wdt:P527 ?subTournament.
   # ?subTournament wdt:P1346 ?winner.
   
   # get the label 
   # ?yearlyWimbledonTournament sc:name ?yearlyWimbledonTournamentName .
   # ?subTournament sc:name ?subTournamentName.
   # ?winner sc:name ?winnerName.
   # ?winner wdt:P569 ?dob
   FILTER (?dob > "1975-01-01"^^xsd:date)
}
ORDER BY ASC (?dob)
LIMIT 20

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q746693'), ('yearlyWimbledonTournamentName', '2005 Wimbledon Championships'), ('subTournament', 'http://www.wikidata.org/entity/Q2397886'), ('subTournamentName', '2005 Wimbledon Championships – Mixed Doubles'), ('winner', 'http://www.wikidata.org/entity/Q210695'), ('winnerName', 'Mary Pierce'), ('dob', '1975-01-15T00:00:00Z')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q832484'), ('yearlyWimbledonTournamentName', '2003 Wimbledon Championships'), ('subTournament', 'http://www.wikidata.org/entity/Q1575145'), ('subTournamentName', "2003 Wimbledon Championships – Women's Doubles"), ('winner', 'http://www.wikidata.org/entity/Q229100'), ('winnerName', 'Ai Sugiyama'), ('dob', '1975-07-05T00:00:00Z')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q245073'), ('yearlyWimbledonTournamentName', '2011 Wimbledon Championships'), ('subTournament', 'http://www.wikidata.org/entity/Q607519'), ('subTournamentName', "2011 Wimbledon Championships – Women's Doubles"), ('winner', 'http://www.wikidata.org/entity/Q234480'), ('winnerName', 'Květa Peschke'), ('dob', '1975-07-09T00:00:00Z')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q840901'), ('yearlyWimbledonTournamentName', '2002 Wimbledon Championships'), ('subTournament', 'http://www.wikidata.org/entity/Q3037789'), ('subTournamentName', '2002 Wimbledon Championships – Mixed Doubles'), ('winner', 'http://www.wikidata.org/entity/Q233231'), ('winnerName', 'Elena Likhovtseva'), ('dob', '1975-09-08T00:00:00Z')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q746693'), ('yearlyWimbledonTournamentName', '2005 Wimbledon Championships'), ('subTournament', 'http://www.wikidata.org/entity/Q538268'), ('subTournamentName', "2005 Wimbledon Championships – Men's Doubles"), ('winner', 'http://www.wikidata.org/entity/Q369885'), ('winnerName', 'Stephen Huss'), ('dob', '1975-12-10T00:00:00Z')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q15854765'), ('yearlyWimbledonTournamentName', '2014 Wimbledon Championships'), ('subTournament', 'http://www.wikidata.org/entity/Q17173009'), ('subTournamentName', '2014 Wimbledon Championships – Mixed Doubles'), ('winner', 'http://www.wikidata.org/entity/Q310419'), ('winnerName', 'Nenad Zimonjić'), ('dob', '1976-06-04T00:00:00Z')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q727406'), ('yearlyWimbledonTournamentName', '1999 Wimbledon Championships'), ('subTournament', 'http://www.wikidata.org/entity/Q767231'), ('subTournamentName', "1999 Wimbledon Championships – Women's Singles"), ('winner', 'http://www.wikidata.org/entity/Q11677'), ('winnerName', 'Lindsay Davenport'), ('dob', '1976-06-08T00:00:00Z')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q727406'), ('yearlyWimbledonTournamentName', '1999 Wimbledon Championships'), ('subTournament', 'http://www.wikidata.org/entity/Q1237966'), ('subTournamentName', "1999 Wimbledon Championships – Women's Doubles"), ('winner', 'http://www.wikidata.org/entity/Q11677'), ('winnerName', 'Lindsay Davenport'), ('dob', '1976-06-08T00:00:00Z')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q746693'), ('yearlyWimbledonTournamentName', '2005 Wimbledon Championships'), ('subTournament', 'http://www.wikidata.org/entity/Q1855928'), ('subTournamentName', "2005 Wimbledon Championships – Women's Doubles"), ('winner', 'http://www.wikidata.org/entity/Q53565'), ('winnerName', 'Liezel Huber'), ('dob', '1976-08-21T00:00:00Z')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q746669'), ('yearlyWimbledonTournamentName', '2007 Wimbledon Championships'), ('subTournament', 'http://www.wikidata.org/entity/Q578947'), ('subTournamentName', "2007 Wimbledon Championships – Women's Doubles"), ('winner', 'http://www.wikidata.org/entity/Q53565'), ('winnerName', 'Liezel Huber'), ('dob', '1976-08-21T00:00:00Z')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q912527'), ('yearlyWimbledonTournamentName', '2001 Wimbledon Championships'), ('subTournament', 'http://www.wikidata.org/entity/Q3037791'), ('subTournamentName', '2001 Wimbledon Championships – Mixed Doubles'), ('winner', 'http://www.wikidata.org/entity/Q521418'), ('winnerName', 'Leoš Friedl'), ('dob', '1977-01-01T00:00:00Z')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q512632'), ('yearlyWimbledonTournamentName', '1998 Wimbledon Championships'), ('subTournament', 'http://www.wikidata.org/entity/Q1984756'), ('subTournamentName', '1998 Wimbledon Championships – Mixed Doubles'), ('winner', 'http://www.wikidata.org/entity/Q221359'), ('winnerName', 'Max Mirnyi'), ('dob', '1977-07-06T00:00:00Z')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q746669'), ('yearlyWimbledonTournamentName', '2007 Wimbledon Championships'), ('subTournament', 'http://www.wikidata.org/entity/Q662965'), ('subTournamentName', "2007 Wimbledon Championships – Men's Doubles"), ('winner', 'http://www.wikidata.org/entity/Q299944'), ('winnerName', 'Arnaud Clément'), ('dob', '1977-12-17T00:00:00Z')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q727406'), ('yearlyWimbledonTournamentName', '1999 Wimbledon Championships'), ('subTournament', 'http://www.wikidata.org/entity/Q1237966'), ('subTournamentName', "1999 Wimbledon Championships – Women's Doubles"), ('winner', 'http://www.wikidata.org/entity/Q225589'), ('winnerName', 'Corina Morariu'), ('dob', '1978-01-26T00:00:00Z')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q388312'), ('yearlyWimbledonTournamentName', '2008 Wimbledon Championships'), ('subTournament', 'http://www.wikidata.org/entity/Q921541'), ('subTournamentName', '2008 Wimbledon Championships – Mixed Doubles'), ('winner', 'http://www.wikidata.org/entity/Q53340'), ('winnerName', 'Bob Bryan'), ('dob', '1978-04-29T00:00:00Z')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q289587'), ('yearlyWimbledonTournamentName', '2012 Wimbledon Championships'), ('subTournament', 'http://www.wikidata.org/entity/Q524340'), ('subTournamentName', '2012 Wimbledon Championships – Mixed Doubles'), ('winner', 'http://www.wikidata.org/entity/Q53342'), ('winnerName', 'Mike Bryan'), ('dob', '1978-04-29T00:00:00Z')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q241184'), ('yearlyWimbledonTournamentName', '2006 Wimbledon Championships'), ('subTournament', 'http://www.wikidata.org/entity/Q1395843'), ('subTournamentName', "2006 Wimbledon Championships – Men's Doubles"), ('winner', 'http://www.wikidata.org/entity/Q53340'), ('winnerName', 'Bob Bryan'), ('dob', '1978-04-29T00:00:00Z')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q30085309'), ('yearlyWimbledonTournamentName', '2018 Wimbledon Championships'), ('subTournament', 'http://www.wikidata.org/entity/Q32357790'), ('subTournamentName', "2018 Wimbledon Championships – Men's Doubles"), ('winner', 'http://www.wikidata.org/entity/Q53342'), ('winnerName', 'Mike Bryan'), ('dob', '1978-04-29T00:00:00Z')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q245073'), ('yearlyWimbledonTournamentName', '2011 Wimbledon Championships'), ('subTournament', 'http://www.wikidata.org/entity/Q180213'), ('subTournamentName', "2011 Wimbledon Championships – Men's Doubles"), ('winner', 'http://www.wikidata.org/entity/Q53340'), ('winnerName', 'Bob Bryan'), ('dob', '1978-04-29T00:00:00Z')]
# [('yearlyWimbledonTournament', 'http://www.wikidata.org/entity/Q559726'), ('yearlyWimbledonTournamentName', '2013 Wimbledon Championships'), ('subTournament', 'http://www.wikidata.org/entity/Q13463436'), ('subTournamentName', "2013 Wimbledon Championships – Men's Doubles"), ('winner', 'http://www.wikidata.org/entity/Q53340'), ('winnerName', 'Bob Bryan'), ('dob', '1978-04-29T00:00:00Z')]
# 20

# %%
# write your queries

# Consider the tennis players born after 1975, return who won more Grand Slams and cut the result to the top-10 (the result set must be a list of triples player IRI, label and #victories).

# from task3 [('obj', 'http://www.wikidata.org/entity/Q41520'), ('objName', 'Wimbledon Championships')]
# <---P31 instance of -- Q30085309 '2018 Wimbledon Championships'
# --P527 ('has part')--> Q30098268 "2018 Wimbledon Championships – Women's Singles" --> P1346 ('winner') -->

# 1 - getting all winner of yearly Wimbledon Tournament
# 2 - select only those who was born after 1975
# 3 - counting their victories

queryString = """

PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
SELECT DISTINCT ?winner ?winnerName ?dob (COUNT(*) AS ?victories)
WHERE {
   # BACKWARD DISCOVERY
   # ?yearlyWimbledonTournament ?p wd:Q41520.
   # ?yearlyWimbledonTournament wdt:P527 ?subTournament.
   # ?subTournament wdt:P1346 ?winner.
   
   # get the label 
   # ?yearlyWimbledonTournament sc:name ?yearlyWimbledonTournamentName .
   # ?subTournament sc:name ?subTournamentName.
   # ?winner sc:name ?winnerName.
   # ?winner wdt:P569 ?dob
   FILTER (?dob > "1975-01-01"^^xsd:date)
}
GROUP BY ?winner ?winnerName ?dob
ORDER BY ASC (?dob)
LIMIT 20

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('winner', 'http://www.wikidata.org/entity/Q210695'), ('winnerName', 'Mary Pierce'), ('dob', '1975-01-15T00:00:00Z'), ('victories', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q229100'), ('winnerName', 'Ai Sugiyama'), ('dob', '1975-07-05T00:00:00Z'), ('victories', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q234480'), ('winnerName', 'Květa Peschke'), ('dob', '1975-07-09T00:00:00Z'), ('victories', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q233231'), ('winnerName', 'Elena Likhovtseva'), ('dob', '1975-09-08T00:00:00Z'), ('victories', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q369885'), ('winnerName', 'Stephen Huss'), ('dob', '1975-12-10T00:00:00Z'), ('victories', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q310419'), ('winnerName', 'Nenad Zimonjić'), ('dob', '1976-06-04T00:00:00Z'), ('victories', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q11677'), ('winnerName', 'Lindsay Davenport'), ('dob', '1976-06-08T00:00:00Z'), ('victories', '2')]
# [('winner', 'http://www.wikidata.org/entity/Q53565'), ('winnerName', 'Liezel Huber'), ('dob', '1976-08-21T00:00:00Z'), ('victories', '2')]
# [('winner', 'http://www.wikidata.org/entity/Q521418'), ('winnerName', 'Leoš Friedl'), ('dob', '1977-01-01T00:00:00Z'), ('victories', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q221359'), ('winnerName', 'Max Mirnyi'), ('dob', '1977-07-06T00:00:00Z'), ('victories', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q299944'), ('winnerName', 'Arnaud Clément'), ('dob', '1977-12-17T00:00:00Z'), ('victories', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q225589'), ('winnerName', 'Corina Morariu'), ('dob', '1978-01-26T00:00:00Z'), ('victories', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q53340'), ('winnerName', 'Bob Bryan'), ('dob', '1978-04-29T00:00:00Z'), ('victories', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q53342'), ('winnerName', 'Mike Bryan'), ('dob', '1978-04-29T00:00:00Z'), ('victories', '2')]
# [('winner', 'http://www.wikidata.org/entity/Q229128'), ('winnerName', 'Cara Black'), ('dob', '1979-02-17T00:00:00Z'), ('victories', '5')]
# [('winner', 'http://www.wikidata.org/entity/Q180872'), ('winnerName', 'Amélie Mauresmo'), ('dob', '1979-07-05T00:00:00Z'), ('victories', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q335318'), ('winnerName', 'Andy Ram'), ('dob', '1980-04-10T00:00:00Z'), ('victories', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q11578'), ('winnerName', 'Venus Williams'), ('dob', '1980-06-17T00:00:00Z'), ('victories', '11')]
# [('winner', 'http://www.wikidata.org/entity/Q457476'), ('winnerName', 'Alexander Peya'), ('dob', '1980-06-27T00:00:00Z'), ('victories', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q134720'), ('winnerName', 'Martina Hingis'), ('dob', '1980-09-30T00:00:00Z'), ('victories', '6')]
# 20

# %%
# write your queries
#CORRECT ORDERING [ONLY WIMBLEDON CHAMPIONSHIPS]

# Consider the tennis players born after 1975, return who won more Grand Slams and cut the result to the top-10 (the result set must be a list of triples player IRI, label and #victories).

# from task3 [('obj', 'http://www.wikidata.org/entity/Q41520'), ('objName', 'Wimbledon Championships')]
# <---P31 instance of -- Q30085309 '2018 Wimbledon Championships'
# --P527 ('has part')--> Q30098268 "2018 Wimbledon Championships – Women's Singles" --> P1346 ('winner') -->

# 1 - getting all winner of yearly Wimbledon Tournament
# 2 - select only those who was born after 1975
# 3 - counting their victories
# 4 - ordering by victories in descenting order

queryString = """

PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
SELECT DISTINCT ?winner ?winnerName ?dob (COUNT(*) AS ?victories)
WHERE {
   # BACKWARD DISCOVERY
   # ?yearlyWimbledonTournament ?p wd:Q41520.
   # ?yearlyWimbledonTournament wdt:P527 ?subTournament.
   # ?subTournament wdt:P1346 ?winner.
   
   # get the label 
   # ?yearlyWimbledonTournament sc:name ?yearlyWimbledonTournamentName .
   # ?subTournament sc:name ?subTournamentName.
   # ?winner sc:name ?winnerName.
   # ?winner wdt:P569 ?dob
   FILTER (?dob > "1975-01-01"^^xsd:date)
}
GROUP BY ?winner ?winnerName ?dob
ORDER BY DESC (?victories)
LIMIT 20

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('winner', 'http://www.wikidata.org/entity/Q11459'), ('winnerName', 'Serena Williams'), ('dob', '1981-09-26T00:00:00Z'), ('victories', '14')]
# [('winner', 'http://www.wikidata.org/entity/Q11578'), ('winnerName', 'Venus Williams'), ('dob', '1980-06-17T00:00:00Z'), ('victories', '11')]
# [('winner', 'http://www.wikidata.org/entity/Q1426'), ('winnerName', 'Roger Federer'), ('dob', '1981-08-08T00:00:00Z'), ('victories', '8')]
# [('winner', 'http://www.wikidata.org/entity/Q5812'), ('winnerName', 'Novak Djokovic'), ('dob', '1987-05-22T00:00:00Z'), ('victories', '6')]
# [('winner', 'http://www.wikidata.org/entity/Q134720'), ('winnerName', 'Martina Hingis'), ('dob', '1980-09-30T00:00:00Z'), ('victories', '6')]
# [('winner', 'http://www.wikidata.org/entity/Q229128'), ('winnerName', 'Cara Black'), ('dob', '1979-02-17T00:00:00Z'), ('victories', '5')]
# [('winner', 'http://www.wikidata.org/entity/Q24574661'), ('winnerName', 'Diede de Groot'), ('dob', '1996-12-19T00:00:00Z'), ('victories', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q53340'), ('winnerName', 'Bob Bryan'), ('dob', '1978-04-29T00:00:00Z'), ('victories', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q232566'), ('winnerName', 'Hsieh Su-wei'), ('dob', '1986-01-04T00:00:00Z'), ('victories', '3')]
# [('winner', 'http://www.wikidata.org/entity/Q223549'), ('winnerName', 'Jürgen Melzer'), ('dob', '1981-05-22T00:00:00Z'), ('victories', '2')]
# [('winner', 'http://www.wikidata.org/entity/Q53565'), ('winnerName', 'Liezel Huber'), ('dob', '1976-08-21T00:00:00Z'), ('victories', '2')]
# [('winner', 'http://www.wikidata.org/entity/Q16224602'), ('winnerName', 'Yui Kamiji'), ('dob', '1994-04-24T00:00:00Z'), ('victories', '2')]
# [('winner', 'http://www.wikidata.org/entity/Q191766'), ('winnerName', 'Samantha Stosur'), ('dob', '1984-03-30T00:00:00Z'), ('victories', '2')]
# [('winner', 'http://www.wikidata.org/entity/Q10125'), ('winnerName', 'Andy Murray'), ('dob', '1987-05-15T00:00:00Z'), ('victories', '2')]
# [('winner', 'http://www.wikidata.org/entity/Q11677'), ('winnerName', 'Lindsay Davenport'), ('dob', '1976-06-08T00:00:00Z'), ('victories', '2')]
# [('winner', 'http://www.wikidata.org/entity/Q10132'), ('winnerName', 'Rafael Nadal'), ('dob', '1986-06-03T00:00:00Z'), ('victories', '2')]
# [('winner', 'http://www.wikidata.org/entity/Q317820'), ('winnerName', 'Jamie Murray'), ('dob', '1986-02-13T00:00:00Z'), ('victories', '2')]
# [('winner', 'http://www.wikidata.org/entity/Q30812'), ('winnerName', 'Petra Kvitová'), ('dob', '1990-03-08T00:00:00Z'), ('victories', '2')]
# [('winner', 'http://www.wikidata.org/entity/Q53342'), ('winnerName', 'Mike Bryan'), ('dob', '1978-04-29T00:00:00Z'), ('victories', '2')]
# [('winner', 'http://www.wikidata.org/entity/Q13538'), ('winnerName', 'Henri Kontinen'), ('dob', '1990-06-19T00:00:00Z'), ('victories', '1')]
# 20

# %%
# write your queries

# Consider the tennis players born after 1975, return who won more Grand Slams and cut the result to the top-10 (the result set must be a list of triples player IRI, label and #victories).

# from task3 [('obj', 'http://www.wikidata.org/entity/Q41520'), ('objName', 'Wimbledon Championships')]
# <---P31 instance of -- Q30085309 '2018 Wimbledon Championships'
# --P527 ('has part')--> Q30098268 "2018 Wimbledon Championships – Women's Singles" --> P1346 ('winner') -->

# 1 - getting all winner of yearly Wimbledon Tournament
# 2 - select only those who was born after 1975
# 3 - counting their victories
# 4 - ordering by victories in descenting order
# 5 - limiting to only top 10 distinct winners

queryString = """

PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
SELECT DISTINCT ?winner ?winnerName (COUNT(*) AS ?victories)
WHERE {
   # BACKWARD DISCOVERY
   # ?yearlyWimbledonTournament ?p wd:Q41520.
   # ?yearlyWimbledonTournament wdt:P527 ?subTournament.
   # ?subTournament wdt:P1346 ?winner.
   
   # get the label 
   # ?yearlyWimbledonTournament sc:name ?yearlyWimbledonTournamentName .
   # ?subTournament sc:name ?subTournamentName.
   # ?winner sc:name ?winnerName.
   # ?winner wdt:P569 ?dob
   FILTER (?dob > "1975-01-01"^^xsd:date)
}
GROUP BY ?winner ?winnerName
ORDER BY DESC (?victories)
LIMIT 10

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('winner', 'http://www.wikidata.org/entity/Q11459'), ('winnerName', 'Serena Williams'), ('victories', '14')]
# [('winner', 'http://www.wikidata.org/entity/Q11578'), ('winnerName', 'Venus Williams'), ('victories', '11')]
# [('winner', 'http://www.wikidata.org/entity/Q1426'), ('winnerName', 'Roger Federer'), ('victories', '8')]
# [('winner', 'http://www.wikidata.org/entity/Q134720'), ('winnerName', 'Martina Hingis'), ('victories', '6')]
# [('winner', 'http://www.wikidata.org/entity/Q5812'), ('winnerName', 'Novak Djokovic'), ('victories', '6')]
# [('winner', 'http://www.wikidata.org/entity/Q229128'), ('winnerName', 'Cara Black'), ('victories', '5')]
# [('winner', 'http://www.wikidata.org/entity/Q53340'), ('winnerName', 'Bob Bryan'), ('victories', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q24574661'), ('winnerName', 'Diede de Groot'), ('victories', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q232566'), ('winnerName', 'Hsieh Su-wei'), ('victories', '3')]
# [('winner', 'http://www.wikidata.org/entity/Q53342'), ('winnerName', 'Mike Bryan'), ('victories', '2')]
# 10

# %%
# write your queries
# CORRECT ORDERING [FRENCH OPEN]

# Consider the tennis players born after 1975, return who won more Grand Slams and cut the result to the top-10 (the result set must be a list of triples player IRI, label and #victories).

# from task3 [('obj', 'http://www.wikidata.org/entity/Q41520'), ('objName', 'Wimbledon Championships')]
# <---P31 instance of -- Q30085309 '2018 Wimbledon Championships'
# --P527 ('has part')--> Q30098268 "2018 Wimbledon Championships – Women's Singles" --> P1346 ('winner') -->
# Results TASK 3
#[('obj', 'http://www.wikidata.org/entity/Q43605'), ('objName', 'French Open')]
#[('obj', 'http://www.wikidata.org/entity/Q123577'), ('objName', 'US Open')]
#[('obj', 'http://www.wikidata.org/entity/Q41520'), ('objName', 'Wimbledon Championships')]
#[('obj', 'http://www.wikidata.org/entity/Q60874'), ('objName', 'Australian Open')]

# 1* - getting all winner of yearly French Open
# 2 - select only those who was born after 1975
# 3 - counting their victories
# 4 - ordering by victories in descenting order
# 5 - limiting to only top 10 distinct winners


queryString = """

PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
SELECT DISTINCT ?winner ?winnerName ?dob (COUNT(*) AS ?victories)
WHERE {
   # BACKWARD DISCOVERY
   # ?yearlyTournament ?p wd:Q43605.
   # ?yearlyTournament wdt:P527 ?subTournament.
   # ?subTournament wdt:P1346 ?winner.
   
   # get the label 
   # ?yearlyTournament sc:name ?yearlyTournamentName .
   # ?subTournament sc:name ?subTournamentName.
   # ?winner sc:name ?winnerName.
   # ?winner wdt:P569 ?dob
   FILTER (?dob > "1975-01-01"^^xsd:date)
}
GROUP BY ?winner ?winnerName ?dob
ORDER BY DESC (?victories)
LIMIT 10

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('winner', 'http://www.wikidata.org/entity/Q10132'), ('winnerName', 'Rafael Nadal'), ('dob', '1986-06-03T00:00:00Z'), ('victories', '13')]
# [('winner', 'http://www.wikidata.org/entity/Q11459'), ('winnerName', 'Serena Williams'), ('dob', '1981-09-26T00:00:00Z'), ('victories', '5')]
# [('winner', 'http://www.wikidata.org/entity/Q16224602'), ('winnerName', 'Yui Kamiji'), ('dob', '1994-04-24T00:00:00Z'), ('victories', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q24574661'), ('winnerName', 'Diede de Groot'), ('dob', '1996-12-19T00:00:00Z'), ('victories', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q11682'), ('winnerName', 'Justine Henin'), ('dob', '1982-06-01T00:00:00Z'), ('victories', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q11052500'), ('winnerName', 'Barbora Krejčíková'), ('dob', '1995-12-18T00:00:00Z'), ('victories', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q190723'), ('winnerName', 'Gustavo Kuerten'), ('dob', '1976-09-10T00:00:00Z'), ('victories', '3')]
# [('winner', 'http://www.wikidata.org/entity/Q242959'), ('winnerName', 'Kristina Mladenovic'), ('dob', '1993-05-14T00:00:00Z'), ('victories', '3')]
# [('winner', 'http://www.wikidata.org/entity/Q239765'), ('winnerName', 'Tímea Babos'), ('dob', '1993-05-10T00:00:00Z'), ('victories', '3')]
# [('winner', 'http://www.wikidata.org/entity/Q54537'), ('winnerName', 'Bethanie Mattek-Sands'), ('dob', '1985-03-23T00:00:00Z'), ('victories', '3')]
# 10

# %%
# write your queries
# CORRECT ORDERING [US OPEN]

# Consider the tennis players born after 1975, return who won more Grand Slams and cut the result to the top-10 (the result set must be a list of triples player IRI, label and #victories).

# from task3 [('obj', 'http://www.wikidata.org/entity/Q41520'), ('objName', 'Wimbledon Championships')]
# <---P31 instance of -- Q30085309 '2018 Wimbledon Championships'
# --P527 ('has part')--> Q30098268 "2018 Wimbledon Championships – Women's Singles" --> P1346 ('winner') -->
# Results TASK 3
#[('obj', 'http://www.wikidata.org/entity/Q43605'), ('objName', 'French Open')]
#[('obj', 'http://www.wikidata.org/entity/Q123577'), ('objName', 'US Open')]
#[('obj', 'http://www.wikidata.org/entity/Q41520'), ('objName', 'Wimbledon Championships')]
#[('obj', 'http://www.wikidata.org/entity/Q60874'), ('objName', 'Australian Open')]

# 1* - getting all winner of yearly US Open
# 2 - select only those who was born after 1975
# 3 - counting their victories
# 4 - ordering by victories in descenting order
# 5 - limiting to only top 10 distinct winners

queryString = """

PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
SELECT DISTINCT ?winner ?winnerName ?dob (COUNT(*) AS ?victories)
WHERE {
   # BACKWARD DISCOVERY
   # ?yearlyTournament ?p wd:Q123577.
   # ?yearlyTournament wdt:P527 ?subTournament.
   # ?subTournament wdt:P1346 ?winner.
   
   # get the label 
   # ?yearlyTournament sc:name ?yearlyTournamentName .
   # ?subTournament sc:name ?subTournamentName.
   # ?winner sc:name ?winnerName.
   # ?winner wdt:P569 ?dob
   FILTER (?dob > "1975-01-01"^^xsd:date)
}
GROUP BY ?winner ?winnerName ?dob
ORDER BY DESC (?victories)
LIMIT 10

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('winner', 'http://www.wikidata.org/entity/Q11459'), ('winnerName', 'Serena Williams'), ('dob', '1981-09-26T00:00:00Z'), ('victories', '6')]
# [('winner', 'http://www.wikidata.org/entity/Q26951148'), ('winnerName', 'Alfie Hewett'), ('dob', '1997-12-06T00:00:00Z'), ('victories', '5')]
# [('winner', 'http://www.wikidata.org/entity/Q24574661'), ('winnerName', 'Diede de Groot'), ('dob', '1996-12-19T00:00:00Z'), ('victories', '5')]
# [('winner', 'http://www.wikidata.org/entity/Q134720'), ('winnerName', 'Martina Hingis'), ('dob', '1980-09-30T00:00:00Z'), ('victories', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q10132'), ('winnerName', 'Rafael Nadal'), ('dob', '1986-06-03T00:00:00Z'), ('victories', '3')]
# [('winner', 'http://www.wikidata.org/entity/Q54537'), ('winnerName', 'Bethanie Mattek-Sands'), ('dob', '1985-03-23T00:00:00Z'), ('victories', '3')]
# [('winner', 'http://www.wikidata.org/entity/Q11581'), ('winnerName', 'Andrea Sestini Hlaváčková'), ('dob', '1986-08-10T00:00:00Z'), ('victories', '2')]
# [('winner', 'http://www.wikidata.org/entity/Q16224602'), ('winnerName', 'Yui Kamiji'), ('dob', '1994-04-24T00:00:00Z'), ('victories', '2')]
# [('winner', 'http://www.wikidata.org/entity/Q229128'), ('winnerName', 'Cara Black'), ('dob', '1979-02-17T00:00:00Z'), ('victories', '2')]
# [('winner', 'http://www.wikidata.org/entity/Q66309318'), ('winnerName', 'Robin Montgomery'), ('dob', '2004-09-05T00:00:00Z'), ('victories', '2')]
# 10

# %%
# write your queries
# CORRECT ORDERING [Australian OPEN]

# Consider the tennis players born after 1975, return who won more Grand Slams and cut the result to the top-10 (the result set must be a list of triples player IRI, label and #victories).

# from task3 [('obj', 'http://www.wikidata.org/entity/Q41520'), ('objName', 'Wimbledon Championships')]
# <---P31 instance of -- Q30085309 '2018 Wimbledon Championships'
# --P527 ('has part')--> Q30098268 "2018 Wimbledon Championships – Women's Singles" --> P1346 ('winner') -->
# Results TASK 3
#[('obj', 'http://www.wikidata.org/entity/Q43605'), ('objName', 'French Open')]
#[('obj', 'http://www.wikidata.org/entity/Q123577'), ('objName', 'US Open')]
#[('obj', 'http://www.wikidata.org/entity/Q41520'), ('objName', 'Wimbledon Championships')]
#[('obj', 'http://www.wikidata.org/entity/Q60874'), ('objName', 'Australian Open')]

# 1* - getting all winner of yearly Australian Open
# 2 - select only those who was born after 1975
# 3 - counting their victories
# 4 - ordering by victories in descenting order
# 5 - limiting to only top 10 distinct winners

queryString = """

PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
SELECT DISTINCT ?winner ?winnerName ?dob (COUNT(*) AS ?victories)
WHERE {
   # BACKWARD DISCOVERY
   # ?yearlyTournament ?p wd:Q60874.
   # ?yearlyTournament wdt:P527 ?subTournament.
   # ?subTournament wdt:P1346 ?winner.
   
   # get the label 
   # ?yearlyTournament sc:name ?yearlyTournamentName .
   # ?subTournament sc:name ?subTournamentName.
   # ?winner sc:name ?winnerName.
   # ?winner wdt:P569 ?dob
   FILTER (?dob > "1975-01-01"^^xsd:date)
}
GROUP BY ?winner ?winnerName ?dob
ORDER BY DESC (?victories)
LIMIT 10

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('winner', 'http://www.wikidata.org/entity/Q11459'), ('winnerName', 'Serena Williams'), ('dob', '1981-09-26T00:00:00Z'), ('victories', '11')]
# [('winner', 'http://www.wikidata.org/entity/Q134720'), ('winnerName', 'Martina Hingis'), ('dob', '1980-09-30T00:00:00Z'), ('victories', '10')]
# [('winner', 'http://www.wikidata.org/entity/Q5812'), ('winnerName', 'Novak Djokovic'), ('dob', '1987-05-22T00:00:00Z'), ('victories', '9')]
# [('winner', 'http://www.wikidata.org/entity/Q53340'), ('winnerName', 'Bob Bryan'), ('dob', '1978-04-29T00:00:00Z'), ('victories', '6')]
# [('winner', 'http://www.wikidata.org/entity/Q1426'), ('winnerName', 'Roger Federer'), ('dob', '1981-08-08T00:00:00Z'), ('victories', '6')]
# [('winner', 'http://www.wikidata.org/entity/Q53342'), ('winnerName', 'Mike Bryan'), ('dob', '1978-04-29T00:00:00Z'), ('victories', '6')]
# [('winner', 'http://www.wikidata.org/entity/Q959958'), ('winnerName', 'Shingo Kunieda'), ('dob', '1984-02-21T00:00:00Z'), ('victories', '6')]
# [('winner', 'http://www.wikidata.org/entity/Q11578'), ('winnerName', 'Venus Williams'), ('dob', '1980-06-17T00:00:00Z'), ('victories', '5')]
# [('winner', 'http://www.wikidata.org/entity/Q16224602'), ('winnerName', 'Yui Kamiji'), ('dob', '1994-04-24T00:00:00Z'), ('victories', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q10118'), ('winnerName', 'Victoria Azarenka'), ('dob', '1989-07-31T00:00:00Z'), ('victories', '4')]
# 10

# %%
# write your queries
# ALL

# Consider the tennis players born after 1975, return who won more Grand Slams and cut the result to the top-10 (the result set must be a list of triples player IRI, label and #victories).

# from task3 [('obj', 'http://www.wikidata.org/entity/Q41520'), ('objName', 'Wimbledon Championships')]
# <---P31 instance of -- Q30085309 '2018 Wimbledon Championships'
# --P527 ('has part')--> Q30098268 "2018 Wimbledon Championships – Women's Singles" --> P1346 ('winner') -->
# Results TASK 3
#[('obj', 'http://www.wikidata.org/entity/Q43605'), ('objName', 'French Open')]
#[('obj', 'http://www.wikidata.org/entity/Q123577'), ('objName', 'US Open')]
#[('obj', 'http://www.wikidata.org/entity/Q41520'), ('objName', 'Wimbledon Championships')]
#[('obj', 'http://www.wikidata.org/entity/Q60874'), ('objName', 'Australian Open')]


# 1* - getting all winner of yearly GRAND SLAMS  <--- putting all togheter 
# 2 - select only those who was born after 1975
# 3 - counting their victories
# 4 - ordering by victories in descenting order
# 5 - limiting to only top 10 distinct winners

queryString = """

PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
SELECT DISTINCT ?winner ?winnerName ?dob (COUNT(*) AS ?victories)
WHERE {
   VALUES (?tournament){
   (wd:Q43605)
   (wd:Q123577)
   (wd:Q41520)
   (wd:Q60874)
   }
   # ?yearlyTournament ?p ?tournament.
   # ?yearlyTournament wdt:P527 ?subTournament.
   # ?subTournament wdt:P1346 ?winner.
   
   # get the label 
   # ?yearlyTournament sc:name ?yearlyTournamentName .
   # ?subTournament sc:name ?subTournamentName.
   # ?winner sc:name ?winnerName.
   # ?winner wdt:P569 ?dob
   FILTER (?dob > "1975-01-01"^^xsd:date)
}
GROUP BY ?winner ?winnerName ?dob
ORDER BY DESC (?victories)
LIMIT 10

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('winner', 'http://www.wikidata.org/entity/Q11459'), ('winnerName', 'Serena Williams'), ('dob', '1981-09-26T00:00:00Z'), ('victories', '36')]
# [('winner', 'http://www.wikidata.org/entity/Q134720'), ('winnerName', 'Martina Hingis'), ('dob', '1980-09-30T00:00:00Z'), ('victories', '23')]
# [('winner', 'http://www.wikidata.org/entity/Q11578'), ('winnerName', 'Venus Williams'), ('dob', '1980-06-17T00:00:00Z'), ('victories', '19')]
# [('winner', 'http://www.wikidata.org/entity/Q10132'), ('winnerName', 'Rafael Nadal'), ('dob', '1986-06-03T00:00:00Z'), ('victories', '19')]
# [('winner', 'http://www.wikidata.org/entity/Q5812'), ('winnerName', 'Novak Djokovic'), ('dob', '1987-05-22T00:00:00Z'), ('victories', '19')]
# [('winner', 'http://www.wikidata.org/entity/Q1426'), ('winnerName', 'Roger Federer'), ('dob', '1981-08-08T00:00:00Z'), ('victories', '17')]
# [('winner', 'http://www.wikidata.org/entity/Q24574661'), ('winnerName', 'Diede de Groot'), ('dob', '1996-12-19T00:00:00Z'), ('victories', '16')]
# [('winner', 'http://www.wikidata.org/entity/Q53340'), ('winnerName', 'Bob Bryan'), ('dob', '1978-04-29T00:00:00Z'), ('victories', '14')]
# [('winner', 'http://www.wikidata.org/entity/Q16224602'), ('winnerName', 'Yui Kamiji'), ('dob', '1994-04-24T00:00:00Z'), ('victories', '12')]
# [('winner', 'http://www.wikidata.org/entity/Q53342'), ('winnerName', 'Mike Bryan'), ('dob', '1978-04-29T00:00:00Z'), ('victories', '11')]
# 10

# %%
# write your queries
# ALL

# Consider the tennis players born after 1975, return who won more Grand Slams and cut the result to the top-10 (the result set must be a list of triples player IRI, label and #victories).

# from task3 [('obj', 'http://www.wikidata.org/entity/Q41520'), ('objName', 'Wimbledon Championships')]
# <---P31 instance of -- Q30085309 '2018 Wimbledon Championships'
# --P527 ('has part')--> Q30098268 "2018 Wimbledon Championships – Women's Singles" --> P1346 ('winner') -->
# Results TASK 3
#[('obj', 'http://www.wikidata.org/entity/Q43605'), ('objName', 'French Open')]
#[('obj', 'http://www.wikidata.org/entity/Q123577'), ('objName', 'US Open')]
#[('obj', 'http://www.wikidata.org/entity/Q41520'), ('objName', 'Wimbledon Championships')]
#[('obj', 'http://www.wikidata.org/entity/Q60874'), ('objName', 'Australian Open')]


# 1* - getting all winner of yearly GRAND SLAMS  <--- putting all togheter 
# 2 - select only those who was born after 1975
# 3 - counting their victories
# 4 - ordering by victories in descenting order
# 5 - limiting to only top 10 distinct winners

queryString = """

PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
SELECT DISTINCT ?winner ?winnerName (COUNT(*) AS ?victories)
WHERE {
   VALUES (?tournament){
       (wd:Q43605)
       (wd:Q123577)
       (wd:Q41520)
       (wd:Q60874)
   }
   # ?yearlyTournament ?p ?tournament.
   # ?yearlyTournament wdt:P527 ?subTournament.
   # ?subTournament wdt:P1346 ?winner.
   
   # get the label 
   # ?yearlyTournament sc:name ?yearlyTournamentName .
   # ?subTournament sc:name ?subTournamentName.
   # ?winner sc:name ?winnerName.
   # ?winner wdt:P569 ?dob
   FILTER (?dob > "1975-01-01"^^xsd:date)
}
GROUP BY ?winner ?winnerName
ORDER BY DESC (?victories)
LIMIT 10

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('winner', 'http://www.wikidata.org/entity/Q11459'), ('winnerName', 'Serena Williams'), ('victories', '36')]
# [('winner', 'http://www.wikidata.org/entity/Q134720'), ('winnerName', 'Martina Hingis'), ('victories', '23')]
# [('winner', 'http://www.wikidata.org/entity/Q11578'), ('winnerName', 'Venus Williams'), ('victories', '19')]
# [('winner', 'http://www.wikidata.org/entity/Q10132'), ('winnerName', 'Rafael Nadal'), ('victories', '19')]
# [('winner', 'http://www.wikidata.org/entity/Q5812'), ('winnerName', 'Novak Djokovic'), ('victories', '19')]
# [('winner', 'http://www.wikidata.org/entity/Q1426'), ('winnerName', 'Roger Federer'), ('victories', '17')]
# [('winner', 'http://www.wikidata.org/entity/Q24574661'), ('winnerName', 'Diede de Groot'), ('victories', '16')]
# [('winner', 'http://www.wikidata.org/entity/Q53340'), ('winnerName', 'Bob Bryan'), ('victories', '14')]
# [('winner', 'http://www.wikidata.org/entity/Q16224602'), ('winnerName', 'Yui Kamiji'), ('victories', '12')]
# [('winner', 'http://www.wikidata.org/entity/Q53342'), ('winnerName', 'Mike Bryan'), ('victories', '11')]
# 10

# %%
# write your queries
# ALL

# Consider the tennis players born after 1975, return who won more Grand Slams and cut the result to the top-10 (the result set must be a list of triples player IRI, label and #victories).

# from task3 [('obj', 'http://www.wikidata.org/entity/Q41520'), ('objName', 'Wimbledon Championships')]
# <---P31 instance of -- Q30085309 '2018 Wimbledon Championships'
# --P527 ('has part')--> Q30098268 "2018 Wimbledon Championships – Women's Singles" --> P1346 ('winner') -->
# Results TASK 3
#[('obj', 'http://www.wikidata.org/entity/Q43605'), ('objName', 'French Open')]
#[('obj', 'http://www.wikidata.org/entity/Q123577'), ('objName', 'US Open')]
#[('obj', 'http://www.wikidata.org/entity/Q41520'), ('objName', 'Wimbledon Championships')]
#[('obj', 'http://www.wikidata.org/entity/Q60874'), ('objName', 'Australian Open')]
# P31'), ('pName', 'instance of')]

# 1* - getting all winner of yearly GRAND SLAMS  <--- putting all togheter 
# 2 - select only those who was born after 1975
# 3 - counting their victories
# 4 - ordering by victories in descenting order
# 5 - limiting to only top 10 distinct winners

queryString = """

PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
SELECT DISTINCT ?winner ?winnerName (COUNT(*) AS ?victories)
WHERE {
   VALUES (?tournament){
       (wd:Q43605)
       (wd:Q123577)
       (wd:Q41520)
       (wd:Q60874)
   }
   # ?yearlyTournament wdt:P31 ?tournament.
   # ?yearlyTournament wdt:P527 ?subTournament.
   # ?subTournament wdt:P1346 ?winner.
   
   # get the label 
   # ?yearlyTournament sc:name ?yearlyTournamentName .
   # ?subTournament sc:name ?subTournamentName.
   # ?winner sc:name ?winnerName.
   # ?winner wdt:P569 ?dob
   FILTER (?dob > "1975-01-01"^^xsd:date)
}
GROUP BY ?winner ?winnerName
ORDER BY DESC (?victories)
LIMIT 10

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('winner', 'http://www.wikidata.org/entity/Q11459'), ('winnerName', 'Serena Williams'), ('victories', '36')]
# [('winner', 'http://www.wikidata.org/entity/Q134720'), ('winnerName', 'Martina Hingis'), ('victories', '23')]
# [('winner', 'http://www.wikidata.org/entity/Q11578'), ('winnerName', 'Venus Williams'), ('victories', '19')]
# [('winner', 'http://www.wikidata.org/entity/Q10132'), ('winnerName', 'Rafael Nadal'), ('victories', '19')]
# [('winner', 'http://www.wikidata.org/entity/Q5812'), ('winnerName', 'Novak Djokovic'), ('victories', '19')]
# [('winner', 'http://www.wikidata.org/entity/Q1426'), ('winnerName', 'Roger Federer'), ('victories', '17')]
# [('winner', 'http://www.wikidata.org/entity/Q24574661'), ('winnerName', 'Diede de Groot'), ('victories', '16')]
# [('winner', 'http://www.wikidata.org/entity/Q53340'), ('winnerName', 'Bob Bryan'), ('victories', '14')]
# [('winner', 'http://www.wikidata.org/entity/Q16224602'), ('winnerName', 'Yui Kamiji'), ('victories', '12')]
# [('winner', 'http://www.wikidata.org/entity/Q53342'), ('winnerName', 'Mike Bryan'), ('victories', '11')]
# 10

# %%
# write your queries
# ALL

# Consider the tennis players born after 1975, return who won more Grand Slams and cut the result to the top-10 (the result set must be a list of triples player IRI, label and #victories).

# from task3 [('obj', 'http://www.wikidata.org/entity/Q41520'), ('objName', 'Wimbledon Championships')]
# <---P31 instance of -- Q30085309 '2018 Wimbledon Championships'
# --P527 ('has part')--> Q30098268 "2018 Wimbledon Championships – Women's Singles" --> P1346 ('winner') -->
# Results TASK 3
#[('obj', 'http://www.wikidata.org/entity/Q43605'), ('objName', 'French Open')]
#[('obj', 'http://www.wikidata.org/entity/Q123577'), ('objName', 'US Open')]
#[('obj', 'http://www.wikidata.org/entity/Q41520'), ('objName', 'Wimbledon Championships')]
#[('obj', 'http://www.wikidata.org/entity/Q60874'), ('objName', 'Australian Open')]
# P31'), ('pName', 'instance of')]

# 1* - getting all winner of yearly GRAND SLAMS  <--- putting all togheter 
# 2 - select only those who was born after 1975
# 3 - counting their victories
# 4 - ordering by victories in descenting order
# 5 - limiting to only top 10 distinct winners

# after means 1975 not included ?

queryString = """

PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
SELECT DISTINCT ?winner ?winnerName (COUNT(*) AS ?victories)
WHERE {
   VALUES (?tournament){
       (wd:Q43605)
       (wd:Q123577)
       (wd:Q41520)
       (wd:Q60874)
   }
   # ?yearlyTournament wdt:P31 ?tournament.
   # ?yearlyTournament wdt:P527 ?subTournament.
   # ?subTournament wdt:P1346 ?winner.
   
   # get the label 
   # ?yearlyTournament sc:name ?yearlyTournamentName .
   # ?subTournament sc:name ?subTournamentName.
   # ?winner sc:name ?winnerName.
   # ?winner wdt:P569 ?dob
   FILTER (?dob >= "1976-01-01"^^xsd:date)
}
GROUP BY ?winner ?winnerName
ORDER BY DESC (?victories)
LIMIT 10

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('winner', 'http://www.wikidata.org/entity/Q11459'), ('winnerName', 'Serena Williams'), ('victories', '36')]
# [('winner', 'http://www.wikidata.org/entity/Q134720'), ('winnerName', 'Martina Hingis'), ('victories', '23')]
# [('winner', 'http://www.wikidata.org/entity/Q11578'), ('winnerName', 'Venus Williams'), ('victories', '19')]
# [('winner', 'http://www.wikidata.org/entity/Q10132'), ('winnerName', 'Rafael Nadal'), ('victories', '19')]
# [('winner', 'http://www.wikidata.org/entity/Q5812'), ('winnerName', 'Novak Djokovic'), ('victories', '19')]
# [('winner', 'http://www.wikidata.org/entity/Q1426'), ('winnerName', 'Roger Federer'), ('victories', '17')]
# [('winner', 'http://www.wikidata.org/entity/Q24574661'), ('winnerName', 'Diede de Groot'), ('victories', '16')]
# [('winner', 'http://www.wikidata.org/entity/Q53340'), ('winnerName', 'Bob Bryan'), ('victories', '14')]
# [('winner', 'http://www.wikidata.org/entity/Q16224602'), ('winnerName', 'Yui Kamiji'), ('victories', '12')]
# [('winner', 'http://www.wikidata.org/entity/Q53342'), ('winnerName', 'Mike Bryan'), ('victories', '11')]
# 10

# %% [markdown]
# ### Final query for this task

# %%
# write your final query

# Consider the tennis players born after 1975, return who won more Grand Slams and cut the result to the top-10 
# (the result set must be a list of triples player IRI, label and #victories).

# P31 ('instance of')
# P527 ('has part')
# P1346 ('winner')


queryString = """

PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
SELECT DISTINCT ?winner ?winnerName (COUNT(*) AS ?victories)
WHERE {
    
   VALUES (?tournament){
       (wd:Q43605)   #French Open
       (wd:Q123577)  #US Open
       (wd:Q41520)   #Wimbledon Championships
       (wd:Q60874)   #Australian Open
   }
   #FINDING ALL YEARLY TOURNAMENTS OF EACH TOURNAMENT
   # ?yearlyTournament wdt:P31 ?tournament.
   
   #FINDING ALL SUBTURNAMENTS OF EACH yearlyTournament
   # ?yearlyTournament wdt:P527 ?subTournament.
   
   #FINDING the winner of the SUBTURNAMENTS
   # ?subTournament wdt:P1346 ?winner.
   
   # get the labelS
   # ?yearlyTournament sc:name ?yearlyTournamentName .
   # ?subTournament sc:name ?subTournamentName.
   # ?winner sc:name ?winnerName.
   
   # GETTING THE DATE OF BIRTH
   # ?winner wdt:P569 ?dob
   # FILTERING the players to select only those who were born after 1975
   FILTER (?dob >= "1975-01-01"^^xsd:date)
}

# GROUPING the evertyting w.r.t the player to count the victories
GROUP BY ?winner ?winnerName

# ORDERING in descending order w.r.t. victories
ORDER BY DESC (?victories)

# SELECTING only top 10 players
LIMIT 10

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('winner', 'http://www.wikidata.org/entity/Q11459'), ('winnerName', 'Serena Williams'), ('victories', '36')]
# [('winner', 'http://www.wikidata.org/entity/Q134720'), ('winnerName', 'Martina Hingis'), ('victories', '23')]
# [('winner', 'http://www.wikidata.org/entity/Q11578'), ('winnerName', 'Venus Williams'), ('victories', '19')]
# [('winner', 'http://www.wikidata.org/entity/Q10132'), ('winnerName', 'Rafael Nadal'), ('victories', '19')]
# [('winner', 'http://www.wikidata.org/entity/Q5812'), ('winnerName', 'Novak Djokovic'), ('victories', '19')]
# [('winner', 'http://www.wikidata.org/entity/Q1426'), ('winnerName', 'Roger Federer'), ('victories', '17')]
# [('winner', 'http://www.wikidata.org/entity/Q24574661'), ('winnerName', 'Diede de Groot'), ('victories', '16')]
# [('winner', 'http://www.wikidata.org/entity/Q53340'), ('winnerName', 'Bob Bryan'), ('victories', '14')]
# [('winner', 'http://www.wikidata.org/entity/Q16224602'), ('winnerName', 'Yui Kamiji'), ('victories', '12')]
# [('winner', 'http://www.wikidata.org/entity/Q53342'), ('winnerName', 'Mike Bryan'), ('victories', '11')]
# 10

# %% [markdown]
# #### The result doesn't change if you include or not 1975

# %%
# write your final query

# Consider the tennis players born after 1975, return who won more Grand Slams and cut the result to the top-10 
# (the result set must be a list of triples player IRI, label and #victories).

# P31 ('instance of')
# P527 ('has part')
# P1346 ('winner')


queryString = """

PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
SELECT DISTINCT ?winner ?winnerName (COUNT(*) AS ?victories)
WHERE {
    
   VALUES (?tournament){
       (wd:Q43605)   #French Open
       (wd:Q123577)  #US Open
       (wd:Q41520)   #Wimbledon Championships
       (wd:Q60874)   #Australian Open
   }
   #FINDING ALL YEARLY TOURNAMENTS OF EACH TOURNAMENT
   # ?yearlyTournament wdt:P31 ?tournament.
   
   #FINDING ALL SUBTURNAMENTS OF EACH yearlyTournament
   # ?yearlyTournament wdt:P527 ?subTournament.
   
   #FINDING the winner of the SUBTURNAMENTS
   # ?subTournament wdt:P1346 ?winner.
   
   # get the labelS
   # ?yearlyTournament sc:name ?yearlyTournamentName .
   # ?subTournament sc:name ?subTournamentName.
   # ?winner sc:name ?winnerName.
   
   # GETTING THE DATE OF BIRTH
   # ?winner wdt:P569 ?dob
   # FILTERING the players to select only those who were born after 1975
   FILTER (?dob >= "1976-01-01"^^xsd:date)
}

# GROUPING the evertyting w.r.t the player to count the victories
GROUP BY ?winner ?winnerName

# ORDERING in descending order w.r.t. victories
ORDER BY DESC (?victories)

# SELECTING only top 10 players
LIMIT 10

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('winner', 'http://www.wikidata.org/entity/Q11459'), ('winnerName', 'Serena Williams'), ('victories', '36')]
# [('winner', 'http://www.wikidata.org/entity/Q134720'), ('winnerName', 'Martina Hingis'), ('victories', '23')]
# [('winner', 'http://www.wikidata.org/entity/Q11578'), ('winnerName', 'Venus Williams'), ('victories', '19')]
# [('winner', 'http://www.wikidata.org/entity/Q10132'), ('winnerName', 'Rafael Nadal'), ('victories', '19')]
# [('winner', 'http://www.wikidata.org/entity/Q5812'), ('winnerName', 'Novak Djokovic'), ('victories', '19')]
# [('winner', 'http://www.wikidata.org/entity/Q1426'), ('winnerName', 'Roger Federer'), ('victories', '17')]
# [('winner', 'http://www.wikidata.org/entity/Q24574661'), ('winnerName', 'Diede de Groot'), ('victories', '16')]
# [('winner', 'http://www.wikidata.org/entity/Q53340'), ('winnerName', 'Bob Bryan'), ('victories', '14')]
# [('winner', 'http://www.wikidata.org/entity/Q16224602'), ('winnerName', 'Yui Kamiji'), ('victories', '12')]
# [('winner', 'http://www.wikidata.org/entity/Q53342'), ('winnerName', 'Mike Bryan'), ('victories', '11')]
# 10

# %% [markdown]
# ## Task 7
# Consider the country for sport property of the tennis player (NO Country of citizenship). Return the countries with at least one player who won at least one edition of each Grand Slam (the result set must be a list of country IRI and label).

# %% [markdown]
# #### Finding "country for sport" property.

# %%
# Consider the country for sport property of the tennis player (NO Country of citizenship). 
#   Return the countries with at least one player who won at least one edition of each Grand Slam (the result set must be a list of country IRI and label).

# wd:Q1426 Roger Federer

# finding country for sport property
queryString = """
SELECT DISTINCT ?p ?name
WHERE {
   # bind something
   wd:Q1426 ?p ?obj .
   # get the label
   # ?p sc:name ?name.
}
LIMIT 50
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P1006'), ('name', 'Nationale Thesaurus voor Auteurs ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P103'), ('name', 'native language')]
# [('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('p', 'http://www.wikidata.org/prop/direct/P108'), ('name', 'employer')]
# [('p', 'http://www.wikidata.org/prop/direct/P1263'), ('name', 'NNDB people ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1280'), ('name', 'CONOR.SI ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1284'), ('name', 'Munzinger person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1285'), ('name', 'Munzinger Sport number')]
# [('p', 'http://www.wikidata.org/prop/direct/P1296'), ('name', 'Gran Enciclopèdia Catalana ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1343'), ('name', 'described by source')]
# [('p', 'http://www.wikidata.org/prop/direct/P1344'), ('name', 'participant in')]
# [('p', 'http://www.wikidata.org/prop/direct/P1352'), ('name', 'ranking')]
# [('p', 'http://www.wikidata.org/prop/direct/P140'), ('name', 'religion')]
# [('p', 'http://www.wikidata.org/prop/direct/P1412'), ('name', 'languages spoken, written or signed')]
# [('p', 'http://www.wikidata.org/prop/direct/P1417'), ('name', 'Encyclopædia Britannica Online ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1447'), ('name', 'Sports-Reference.com Olympic athlete ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1532'), ('name', 'country for sport')]
# [('p', 'http://www.wikidata.org/prop/direct/P166'), ('name', 'award received')]
# [('p', 'http://www.wikidata.org/prop/direct/P1695'), ('name', 'NLP ID (unique)')]
# [('p', 'http://www.wikidata.org/prop/direct/P1741'), ('name', 'GTAA ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P18'), ('name', 'image')]
# [('p', 'http://www.wikidata.org/prop/direct/P19'), ('name', 'place of birth')]
# [('p', 'http://www.wikidata.org/prop/direct/P2002'), ('name', 'Twitter username')]
# [('p', 'http://www.wikidata.org/prop/direct/P2003'), ('name', 'Instagram username')]
# [('p', 'http://www.wikidata.org/prop/direct/P2013'), ('name', 'Facebook ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2019'), ('name', 'AllMovie person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2031'), ('name', 'work period (start)')]
# [('p', 'http://www.wikidata.org/prop/direct/P2048'), ('name', 'height')]
# [('p', 'http://www.wikidata.org/prop/direct/P2067'), ('name', 'mass')]
# [('p', 'http://www.wikidata.org/prop/direct/P21'), ('name', 'sex or gender')]
# [('p', 'http://www.wikidata.org/prop/direct/P2121'), ('name', 'prize money')]
# [('p', 'http://www.wikidata.org/prop/direct/P213'), ('name', 'ISNI')]
# [('p', 'http://www.wikidata.org/prop/direct/P214'), ('name', 'VIAF ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2163'), ('name', 'FAST ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P22'), ('name', 'father')]
# [('p', 'http://www.wikidata.org/prop/direct/P2218'), ('name', 'net worth')]
# [('p', 'http://www.wikidata.org/prop/direct/P227'), ('name', 'GND ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2416'), ('name', 'sports discipline competed in')]
# [('p', 'http://www.wikidata.org/prop/direct/P244'), ('name', 'Library of Congress authority ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P25'), ('name', 'mother')]
# [('p', 'http://www.wikidata.org/prop/direct/P2522'), ('name', 'victory')]
# [('p', 'http://www.wikidata.org/prop/direct/P26'), ('name', 'spouse')]
# [('p', 'http://www.wikidata.org/prop/direct/P2604'), ('name', 'Kinopoisk person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2605'), ('name', 'ČSFD person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P268'), ('name', 'Bibliothèque nationale de France ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P269'), ('name', 'IdRef ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P27'), ('name', 'country of citizenship')]
# [('p', 'http://www.wikidata.org/prop/direct/P286'), ('name', 'head coach')]
# [('p', 'http://www.wikidata.org/prop/direct/P2924'), ('name', 'Great Russian Encyclopedia Online ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('name', 'instance of')]
# 50

# %%
# Consider the country for sport property of the tennis player (NO Country of citizenship). 
#   Return the countries with at least one player who won at least one edition of each Grand Slam (the result set must be a list of country IRI and label).

# wd:Q1426 Roger Federer

# finding country for sport property
queryString = """
SELECT DISTINCT ?p ?name
WHERE {
   # bind something
   wd:Q1426 ?p ?obj .
   # get the label
   # ?p sc:name ?name.
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P1006'), ('name', 'Nationale Thesaurus voor Auteurs ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P103'), ('name', 'native language')]
# [('p', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('p', 'http://www.wikidata.org/prop/direct/P108'), ('name', 'employer')]
# [('p', 'http://www.wikidata.org/prop/direct/P1263'), ('name', 'NNDB people ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1280'), ('name', 'CONOR.SI ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1284'), ('name', 'Munzinger person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1285'), ('name', 'Munzinger Sport number')]
# [('p', 'http://www.wikidata.org/prop/direct/P1296'), ('name', 'Gran Enciclopèdia Catalana ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1343'), ('name', 'described by source')]
# [('p', 'http://www.wikidata.org/prop/direct/P1344'), ('name', 'participant in')]
# [('p', 'http://www.wikidata.org/prop/direct/P1352'), ('name', 'ranking')]
# [('p', 'http://www.wikidata.org/prop/direct/P140'), ('name', 'religion')]
# [('p', 'http://www.wikidata.org/prop/direct/P1412'), ('name', 'languages spoken, written or signed')]
# [('p', 'http://www.wikidata.org/prop/direct/P1417'), ('name', 'Encyclopædia Britannica Online ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1447'), ('name', 'Sports-Reference.com Olympic athlete ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1532'), ('name', 'country for sport')]
# [('p', 'http://www.wikidata.org/prop/direct/P166'), ('name', 'award received')]
# [('p', 'http://www.wikidata.org/prop/direct/P1695'), ('name', 'NLP ID (unique)')]
# [('p', 'http://www.wikidata.org/prop/direct/P1741'), ('name', 'GTAA ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P18'), ('name', 'image')]
# [('p', 'http://www.wikidata.org/prop/direct/P19'), ('name', 'place of birth')]
# [('p', 'http://www.wikidata.org/prop/direct/P2002'), ('name', 'Twitter username')]
# [('p', 'http://www.wikidata.org/prop/direct/P2003'), ('name', 'Instagram username')]
# [('p', 'http://www.wikidata.org/prop/direct/P2013'), ('name', 'Facebook ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2019'), ('name', 'AllMovie person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2031'), ('name', 'work period (start)')]
# [('p', 'http://www.wikidata.org/prop/direct/P2048'), ('name', 'height')]
# [('p', 'http://www.wikidata.org/prop/direct/P2067'), ('name', 'mass')]
# [('p', 'http://www.wikidata.org/prop/direct/P21'), ('name', 'sex or gender')]
# [('p', 'http://www.wikidata.org/prop/direct/P2121'), ('name', 'prize money')]
# [('p', 'http://www.wikidata.org/prop/direct/P213'), ('name', 'ISNI')]
# [('p', 'http://www.wikidata.org/prop/direct/P214'), ('name', 'VIAF ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2163'), ('name', 'FAST ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P22'), ('name', 'father')]
# [('p', 'http://www.wikidata.org/prop/direct/P2218'), ('name', 'net worth')]
# [('p', 'http://www.wikidata.org/prop/direct/P227'), ('name', 'GND ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2416'), ('name', 'sports discipline competed in')]
# [('p', 'http://www.wikidata.org/prop/direct/P244'), ('name', 'Library of Congress authority ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P25'), ('name', 'mother')]
# [('p', 'http://www.wikidata.org/prop/direct/P2522'), ('name', 'victory')]
# [('p', 'http://www.wikidata.org/prop/direct/P26'), ('name', 'spouse')]
# [('p', 'http://www.wikidata.org/prop/direct/P2604'), ('name', 'Kinopoisk person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2605'), ('name', 'ČSFD person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P268'), ('name', 'Bibliothèque nationale de France ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P269'), ('name', 'IdRef ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P27'), ('name', 'country of citizenship')]
# [('p', 'http://www.wikidata.org/prop/direct/P286'), ('name', 'head coach')]
# [('p', 'http://www.wikidata.org/prop/direct/P2924'), ('name', 'Great Russian Encyclopedia Online ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('name', 'instance of')]
# [('p', 'http://www.wikidata.org/prop/direct/P3171'), ('name', 'Olympic.org athlete ID (archived version)')]
# [('p', 'http://www.wikidata.org/prop/direct/P3219'), ('name', 'Encyclopædia Universalis ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3221'), ('name', 'New York Times topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3222'), ('name', 'NE.se ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3342'), ('name', 'significant person')]
# [('p', 'http://www.wikidata.org/prop/direct/P3373'), ('name', 'sibling')]
# [('p', 'http://www.wikidata.org/prop/direct/P3388'), ('name', 'LittleSis people ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3417'), ('name', 'Quora topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3427'), ('name', 'AS.com athlete ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P345'), ('name', 'IMDb ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3509'), ('name', 'Dagens Nyheter topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3553'), ('name', 'Zhihu topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3630'), ('name', 'Babelio author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P373'), ('name', 'Commons category')]
# [('p', 'http://www.wikidata.org/prop/direct/P3846'), ('name', 'DBC author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P39'), ('name', 'position held')]
# [('p', 'http://www.wikidata.org/prop/direct/P40'), ('name', 'child')]
# [('p', 'http://www.wikidata.org/prop/direct/P4342'), ('name', 'Store norske leksikon ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P4544'), ('name', 'Tennis Temple player ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P463'), ('name', 'member of')]
# [('p', 'http://www.wikidata.org/prop/direct/P4666'), ('name', 'CineMagia person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P4789'), ('name', "Who's Who UK ID")]
# [('p', 'http://www.wikidata.org/prop/direct/P4985'), ('name', 'TMDb person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5019'), ('name', 'Brockhaus Enzyklopädie online ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5034'), ('name', 'National Library of Korea ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5247'), ('name', 'Giant Bomb ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5337'), ('name', 'Google News topics ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5361'), ('name', 'BNB person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5421'), ('name', 'Trading Card Database person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P551'), ('name', 'residence')]
# [('p', 'http://www.wikidata.org/prop/direct/P552'), ('name', 'handedness')]
# [('p', 'http://www.wikidata.org/prop/direct/P555'), ('name', 'doubles record')]
# [('p', 'http://www.wikidata.org/prop/direct/P5617'), ('name', 'Evene ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P564'), ('name', 'singles record')]
# [('p', 'http://www.wikidata.org/prop/direct/P569'), ('name', 'date of birth')]
# [('p', 'http://www.wikidata.org/prop/direct/P5815'), ('name', 'Olympics.com athlete ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P599'), ('name', 'ITF player ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6262'), ('name', 'Fandom article ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6327'), ('name', 'Goodreads character ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P641'), ('name', 'sport')]
# [('p', 'http://www.wikidata.org/prop/direct/P646'), ('name', 'Freebase ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6553'), ('name', 'personal pronoun')]
# [('p', 'http://www.wikidata.org/prop/direct/P6573'), ('name', 'Klexikon article ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6656'), ('name', 'BHCL ID (former scheme)')]
# [('p', 'http://www.wikidata.org/prop/direct/P6683'), ('name', 'Alexander Turnbull Library ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6868'), ('name', 'Hoopla artist ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P691'), ('name', 'NKCR AUT ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7293'), ('name', 'PLWABN ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P734'), ('name', 'family name')]
# [('p', 'http://www.wikidata.org/prop/direct/P735'), ('name', 'given name')]
# 100

# %%
# Consider the country for sport property of the tennis player (NO Country of citizenship). 
#   Return the countries with at least one player who won at least one edition of each Grand Slam (the result set must be a list of country IRI and label).

# wd:Q1426 Roger Federer --P1532 ('country for sport')-->

queryString = """
SELECT DISTINCT ?obj ?name
WHERE {
   # bind something
   wd:Q1426 wdt:P1532 ?obj .
   # get the label
   # ?obj sc:name ?name.
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('obj', 'http://www.wikidata.org/entity/Q39'), ('name', 'Switzerland')]
# 1

# %% [markdown]
# #### Trying to find a data property over yearly edition of Grand Slam which holds the winner of that edition.

# %%
# write your queries
# Consider the country for sport property of the tennis player (NO Country of citizenship). 
# Return the countries with at least one player who won at least one edition of each Grand Slam (the result set must be a list of country IRI and label).

# [('p', 'http://www.wikidata.org/prop/direct/P1532'), ('name', 'country for sport')]

# P527 ('has part')
# P1346 ('winner')
#[('obj', 'http://www.wikidata.org/entity/Q43605'), ('objName', 'French Open')]
#[('obj', 'http://www.wikidata.org/entity/Q123577'), ('objName', 'US Open')]
#[('obj', 'http://www.wikidata.org/entity/Q41520'), ('objName', 'Wimbledon Championships')]
#[('obj', 'http://www.wikidata.org/entity/Q60874'), ('objName', 'Australian Open')]

# task 6 
queryString = """

PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
SELECT DISTINCT ?winner ?winnerName (COUNT(*) AS ?victories)
WHERE {
   VALUES (?tournament){
       (wd:Q43605)
       (wd:Q123577)
       (wd:Q41520)
       (wd:Q60874)
   }
   # ?yearlyTournament ?p ?tournament.
   # ?yearlyTournament wdt:P527 ?subTournament.
   # ?subTournament wdt:P1346 ?winner.
   
   # get the label 
   # ?yearlyTournament sc:name ?yearlyTournamentName .
   # ?subTournament sc:name ?subTournamentName.
   # ?winner sc:name ?winnerName.
   # ?winner wdt:P569 ?dob
   FILTER (?dob > "1975-01-01"^^xsd:date)
}
GROUP BY ?winner ?winnerName
ORDER BY DESC (?victories)
LIMIT 10

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('winner', 'http://www.wikidata.org/entity/Q11459'), ('winnerName', 'Serena Williams'), ('victories', '36')]
# [('winner', 'http://www.wikidata.org/entity/Q134720'), ('winnerName', 'Martina Hingis'), ('victories', '23')]
# [('winner', 'http://www.wikidata.org/entity/Q11578'), ('winnerName', 'Venus Williams'), ('victories', '19')]
# [('winner', 'http://www.wikidata.org/entity/Q10132'), ('winnerName', 'Rafael Nadal'), ('victories', '19')]
# [('winner', 'http://www.wikidata.org/entity/Q5812'), ('winnerName', 'Novak Djokovic'), ('victories', '19')]
# [('winner', 'http://www.wikidata.org/entity/Q1426'), ('winnerName', 'Roger Federer'), ('victories', '17')]
# [('winner', 'http://www.wikidata.org/entity/Q24574661'), ('winnerName', 'Diede de Groot'), ('victories', '16')]
# [('winner', 'http://www.wikidata.org/entity/Q53340'), ('winnerName', 'Bob Bryan'), ('victories', '14')]
# [('winner', 'http://www.wikidata.org/entity/Q16224602'), ('winnerName', 'Yui Kamiji'), ('victories', '12')]
# [('winner', 'http://www.wikidata.org/entity/Q53342'), ('winnerName', 'Mike Bryan'), ('victories', '11')]
# 10

# %%
# write your queries
# Consider the country for sport property of the tennis player (NO Country of citizenship). 
# Return the countries with at least one player who won at least one edition of each Grand Slam (the result set must be a list of country IRI and label).

# [('p', 'http://www.wikidata.org/prop/direct/P1532'), ('name', 'country for sport')]

# P527 ('has part')
# P1346 ('winner')
#[('obj', 'http://www.wikidata.org/entity/Q43605'), ('objName', 'French Open')]
#[('obj', 'http://www.wikidata.org/entity/Q123577'), ('objName', 'US Open')]
#[('obj', 'http://www.wikidata.org/entity/Q41520'), ('objName', 'Wimbledon Championships')]
#[('obj', 'http://www.wikidata.org/entity/Q60874'), ('objName', 'Australian Open')]

# adapting the previous task by removing date contraint 
# finding ways to group all four tournament by year
queryString = """

PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
SELECT DISTINCT ?yearlyTournament ?yearlyTournamentName
WHERE {
   VALUES (?tournament){
       (wd:Q43605)
       (wd:Q123577)
       (wd:Q41520)
       (wd:Q60874)
   }
   # ?yearlyTournament ?p ?tournament.
   # ?yearlyTournament wdt:P527 ?subTournament.
   # ?subTournament wdt:P1346 ?winner.
   
   # get the label 
   # ?yearlyTournament sc:name ?yearlyTournamentName .
   # ?subTournament sc:name ?subTournamentName.
   # ?winner sc:name ?winnerName.
}
GROUP BY ?yearlyTournament ?yearlyTournamentName
ORDER BY DESC (?yearlyTournamentName)
LIMIT 20

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('yearlyTournament', 'http://www.wikidata.org/entity/Q781434'), ('yearlyTournamentName', 'Australian Goldfields Open')]
# [('yearlyTournament', 'http://www.wikidata.org/entity/Q92032430'), ('yearlyTournamentName', '2021 Wimbledon Championships')]
# [('yearlyTournament', 'http://www.wikidata.org/entity/Q98833450'), ('yearlyTournamentName', '2021 US Open')]
# [('yearlyTournament', 'http://www.wikidata.org/entity/Q99526045'), ('yearlyTournamentName', '2021 French Open')]
# [('yearlyTournament', 'http://www.wikidata.org/entity/Q83629820'), ('yearlyTournamentName', '2021 Australian Open')]
# [('yearlyTournament', 'http://www.wikidata.org/entity/Q66309826'), ('yearlyTournamentName', '2020 US Open')]
# [('yearlyTournament', 'http://www.wikidata.org/entity/Q63367899'), ('yearlyTournamentName', '2020 French Open')]
# [('yearlyTournament', 'http://www.wikidata.org/entity/Q61059083'), ('yearlyTournamentName', '2020 Australian Open')]
# [('yearlyTournament', 'http://www.wikidata.org/entity/Q54093953'), ('yearlyTournamentName', '2019 Wimbledon Championships')]
# [('yearlyTournament', 'http://www.wikidata.org/entity/Q57063604'), ('yearlyTournamentName', '2019 US Open')]
# [('yearlyTournament', 'http://www.wikidata.org/entity/Q54197608'), ('yearlyTournamentName', '2019 French Open')]
# [('yearlyTournament', 'http://www.wikidata.org/entity/Q48213268'), ('yearlyTournamentName', '2019 Australian Open')]
# [('yearlyTournament', 'http://www.wikidata.org/entity/Q30085309'), ('yearlyTournamentName', '2018 Wimbledon Championships')]
# [('yearlyTournament', 'http://www.wikidata.org/entity/Q50391517'), ('yearlyTournamentName', '2018 US Open')]
# [('yearlyTournament', 'http://www.wikidata.org/entity/Q30085136'), ('yearlyTournamentName', '2018 French Open')]
# [('yearlyTournament', 'http://www.wikidata.org/entity/Q42557150'), ('yearlyTournamentName', '2018 Australian Open')]
# [('yearlyTournament', 'http://www.wikidata.org/entity/Q25344121'), ('yearlyTournamentName', '2017 Wimbledon Championships')]
# [('yearlyTournament', 'http://www.wikidata.org/entity/Q28836049'), ('yearlyTournamentName', '2017 US Open')]
# [('yearlyTournament', 'http://www.wikidata.org/entity/Q24387175'), ('yearlyTournamentName', '2017 French Open')]
# [('yearlyTournament', 'http://www.wikidata.org/entity/Q22077628'), ('yearlyTournamentName', '2017 Australian Open')]
# 20

# %%
# write your queries
# Consider the country for sport property of the tennis player (NO Country of citizenship). 
# Return the countries with at least one player who won at least one edition of each Grand Slam (the result set must be a list of country IRI and label).

# [('p', 'http://www.wikidata.org/prop/direct/P1532'), ('name', 'country for sport')]

# P527 ('has part')
# P1346 ('winner')
#[('obj', 'http://www.wikidata.org/entity/Q43605'), ('objName', 'French Open')]
#[('obj', 'http://www.wikidata.org/entity/Q123577'), ('objName', 'US Open')]
#[('obj', 'http://www.wikidata.org/entity/Q41520'), ('objName', 'Wimbledon Championships')]
#[('obj', 'http://www.wikidata.org/entity/Q60874'), ('objName', 'Australian Open')]

# adapting the previous task by removing date contraint 

queryString = """

PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
SELECT DISTINCT ?subTournament ?subTournamentName
WHERE {
   VALUES (?tournament){
       (wd:Q43605)
       (wd:Q123577)
       (wd:Q41520)
       (wd:Q60874)
   }
   # ?yearlyTournament ?p ?tournament.
   # ?yearlyTournament wdt:P527 ?subTournament.
   # ?subTournament wdt:P1346 ?winner.
   
   # get the label 
   # ?yearlyTournament sc:name ?yearlyTournamentName .
   # ?subTournament sc:name ?subTournamentName.
   # ?winner sc:name ?winnerName.
}
GROUP BY ?subTournament ?subTournamentName
ORDER BY DESC (?subTournamentName)
LIMIT 20

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('subTournament', 'http://www.wikidata.org/entity/Q958902'), ('subTournamentName', "US Open 2000 women's doubles")]
# [('subTournament', 'http://www.wikidata.org/entity/Q4339659'), ('subTournamentName', 'Australian Open 2007')]
# [('subTournament', 'http://www.wikidata.org/entity/Q92032445'), ('subTournamentName', "2021 Wimbledon Championships – Women's Singles")]
# [('subTournament', 'http://www.wikidata.org/entity/Q92032438'), ('subTournamentName', "2021 Wimbledon Championships – Women's Doubles")]
# [('subTournament', 'http://www.wikidata.org/entity/Q107434675'), ('subTournamentName', "2021 Wimbledon Championships – Wheelchair Women's Singles")]
# [('subTournament', 'http://www.wikidata.org/entity/Q107434679'), ('subTournamentName', "2021 Wimbledon Championships – Wheelchair Women's Doubles")]
# [('subTournament', 'http://www.wikidata.org/entity/Q107379851'), ('subTournamentName', '2021 Wimbledon Championships – Mixed Doubles')]
# [('subTournament', 'http://www.wikidata.org/entity/Q92032464'), ('subTournamentName', "2021 Wimbledon Championships – Men's Singles")]
# [('subTournament', 'http://www.wikidata.org/entity/Q107345665'), ('subTournamentName', "2021 Wimbledon Championships – Men's Doubles")]
# [('subTournament', 'http://www.wikidata.org/entity/Q98811676'), ('subTournamentName', "2021 US Open – Women's Singles")]
# [('subTournament', 'http://www.wikidata.org/entity/Q108436150'), ('subTournamentName', "2021 US Open – Girls' Singles")]
# [('subTournament', 'http://www.wikidata.org/entity/Q108437590'), ('subTournamentName', "2021 US Open – Girls' Doubles")]
# [('subTournament', 'http://www.wikidata.org/entity/Q99526059'), ('subTournamentName', "2021 French Open – Women's Singles")]
# [('subTournament', 'http://www.wikidata.org/entity/Q99756845'), ('subTournamentName', "2021 French Open – Women's Doubles")]
# [('subTournament', 'http://www.wikidata.org/entity/Q99756902'), ('subTournamentName', '2021 French Open – Mixed Doubles')]
# [('subTournament', 'http://www.wikidata.org/entity/Q99526058'), ('subTournamentName', "2021 French Open – Men's Singles")]
# [('subTournament', 'http://www.wikidata.org/entity/Q99756869'), ('subTournamentName', "2021 French Open – Men's Doubles")]
# [('subTournament', 'http://www.wikidata.org/entity/Q107111218'), ('subTournamentName', "2021 French Open – Girls' Singles")]
# [('subTournament', 'http://www.wikidata.org/entity/Q107125108'), ('subTournamentName', "2021 French Open – Girls' Doubles")]
# [('subTournament', 'http://www.wikidata.org/entity/Q107111575'), ('subTournamentName', "2021 French Open – Boys' Singles")]
# 20

# %%
# write your queries
# Consider the country for sport property of the tennis player (NO Country of citizenship). 
# Return the countries with at least one player who won at least one edition of each Grand Slam (the result set must be a list of country IRI and label).

# [('p', 'http://www.wikidata.org/prop/direct/P1532'), ('name', 'country for sport')]

# P527 ('has part')
# P1346 ('winner')
#[('obj', 'http://www.wikidata.org/entity/Q43605'), ('objName', 'French Open')]
#[('obj', 'http://www.wikidata.org/entity/Q123577'), ('objName', 'US Open')]
#[('obj', 'http://www.wikidata.org/entity/Q41520'), ('objName', 'Wimbledon Championships')]
#[('obj', 'http://www.wikidata.org/entity/Q60874'), ('objName', 'Australian Open')]

# finding ways to group all four tournament by year

queryString = """

PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
SELECT DISTINCT ?p ?pName
WHERE {
   VALUES (?tournament){
       (wd:Q43605)
       (wd:Q123577)
       (wd:Q41520)
       (wd:Q60874)
   }
   # ?yearlyTournament ?p ?tournament.
   # ?yearlyTournament wdt:P527 ?subTournament.
   
   # get the label 
   # ?yearlyTournament sc:name ?yearlyTournamentName .
   # ?subTournament sc:name ?subTournamentName.
   # ?p sc:name ?pName.
}
LIMIT 20

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('p', 'http://www.wikidata.org/prop/direct/P1889'), ('pName', 'different from')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part')]
# 3

# %%
# write your queries
# Consider the country for sport property of the tennis player (NO Country of citizenship). 
# Return the countries with at least one player who won at least one edition of each Grand Slam (the result set must be a list of country IRI and label).

# [('p', 'http://www.wikidata.org/prop/direct/P1532'), ('name', 'country for sport')]

# P527 ('has part')
# P1346 ('winner')
#[('obj', 'http://www.wikidata.org/entity/Q43605'), ('objName', 'French Open')]
#[('obj', 'http://www.wikidata.org/entity/Q123577'), ('objName', 'US Open')]
#[('obj', 'http://www.wikidata.org/entity/Q41520'), ('objName', 'Wimbledon Championships')]
#[('obj', 'http://www.wikidata.org/entity/Q60874'), ('objName', 'Australian Open')]

# finding ways to group all four tournament by year

queryString = """

PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
SELECT DISTINCT ?p ?pName
WHERE {
   VALUES (?tournament){
       (wd:Q43605)
       (wd:Q123577)
       (wd:Q41520)
       (wd:Q60874)
   }
   # ?yearlyTournament ?p ?tournament.
   # ?yearlyTournament wdt:P527 ?subTournament.
   # ?subTournament wdt:P1346 ?winner.
   
   # get the label 
   # ?yearlyTournament sc:name ?yearlyTournamentName .
   # ?subTournament sc:name ?subTournamentName.
   # ?p sc:name ?pName.
}
LIMIT 20

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('p', 'http://www.wikidata.org/prop/direct/P1889'), ('pName', 'different from')]
# 2

# %%
# write your queries
# Consider the country for sport property of the tennis player (NO Country of citizenship). 
# Return the countries with at least one player who won at least one edition of each Grand Slam (the result set must be a list of country IRI and label).

# [('p', 'http://www.wikidata.org/prop/direct/P1532'), ('name', 'country for sport')]

# P31 ('instance of')
# P527 ('has part')
# P1346 ('winner')

#[('obj', 'http://www.wikidata.org/entity/Q43605'), ('objName', 'French Open')]
#[('obj', 'http://www.wikidata.org/entity/Q123577'), ('objName', 'US Open')]
#[('obj', 'http://www.wikidata.org/entity/Q41520'), ('objName', 'Wimbledon Championships')]
#[('obj', 'http://www.wikidata.org/entity/Q60874'), ('objName', 'Australian Open')]

# finding ways to group all four tournament by year

queryString = """

PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
SELECT DISTINCT ?p ?pName ?obj
WHERE {
   VALUES (?tournament){
       (wd:Q43605)
       (wd:Q123577)
       (wd:Q41520)
       (wd:Q60874)
   }
   # ?yearlyTournament wdt:P31 ?tournament.
   # ?yearlyTournament wdt:P527 ?subTournament.
   # ?subTournament ?p ?obj.
   
   # get the label 
   # ?yearlyTournament sc:name ?yearlyTournamentName .
   # ?subTournament sc:name ?subTournamentName.
   # ?p sc:name ?pName.
}
LIMIT 20

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P1132'), ('pName', 'number of participants'), ('obj', '128')]
# [('p', 'http://www.wikidata.org/prop/direct/P1269'), ('pName', 'facet of'), ('obj', 'http://www.wikidata.org/entity/Q731265')]
# [('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner'), ('obj', 'http://www.wikidata.org/entity/Q52453')]
# [('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner'), ('obj', 'http://www.wikidata.org/entity/Q134720')]
# [('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner'), ('obj', 'http://www.wikidata.org/entity/Q296282')]
# [('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner'), ('obj', 'http://www.wikidata.org/entity/Q1348791')]
# [('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner'), ('obj', 'http://www.wikidata.org/entity/Q1508952')]
# [('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner'), ('obj', 'http://www.wikidata.org/entity/Q22958938')]
# [('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner'), ('obj', 'http://www.wikidata.org/entity/Q22959065')]
# [('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner'), ('obj', 'http://www.wikidata.org/entity/Q1426')]
# [('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner'), ('obj', 'http://www.wikidata.org/entity/Q34276')]
# [('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner'), ('obj', 'http://www.wikidata.org/entity/Q77178')]
# [('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner'), ('obj', 'http://www.wikidata.org/entity/Q264493')]
# [('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner'), ('obj', 'http://www.wikidata.org/entity/Q270414')]
# [('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner'), ('obj', 'http://www.wikidata.org/entity/Q712208')]
# [('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner'), ('obj', 'http://www.wikidata.org/entity/Q104506')]
# [('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner'), ('obj', 'http://www.wikidata.org/entity/Q241727')]
# [('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner'), ('obj', 'http://www.wikidata.org/entity/Q53325')]
# [('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner'), ('obj', 'http://www.wikidata.org/entity/Q2903676')]
# [('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner'), ('obj', 'http://www.wikidata.org/entity/Q1144091')]
# 20

# %%
# write your queries
# Consider the country for sport property of the tennis player (NO Country of citizenship). 
# Return the countries with at least one player who won at least one edition of each Grand Slam (the result set must be a list of country IRI and label).

# [('p', 'http://www.wikidata.org/prop/direct/P1532'), ('name', 'country for sport')]

# P31 ('instance of')
# P527 ('has part')
# P1346 ('winner')

#[('obj', 'http://www.wikidata.org/entity/Q43605'), ('objName', 'French Open')]
#[('obj', 'http://www.wikidata.org/entity/Q123577'), ('objName', 'US Open')]
#[('obj', 'http://www.wikidata.org/entity/Q41520'), ('objName', 'Wimbledon Championships')]
#[('obj', 'http://www.wikidata.org/entity/Q60874'), ('objName', 'Australian Open')]

# finding ways to group all four tournament by year

queryString = """

PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
SELECT DISTINCT ?p ?pName
WHERE {
   VALUES (?tournament){
       (wd:Q43605)
       (wd:Q123577)
       (wd:Q41520)
       (wd:Q60874)
   }
   # ?yearlyTournament wdt:P31 ?tournament.
   # ?yearlyTournament wdt:P527 ?subTournament.
   # ?subTournament ?p ?obj.
   
   # get the label 
   # ?yearlyTournament sc:name ?yearlyTournamentName .
   # ?subTournament sc:name ?subTournamentName.
   # ?p sc:name ?pName.
}
LIMIT 50

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P1132'), ('pName', 'number of participants')]
# [('p', 'http://www.wikidata.org/prop/direct/P1269'), ('pName', 'facet of')]
# [('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner')]
# [('p', 'http://www.wikidata.org/prop/direct/P155'), ('pName', 'follows')]
# [('p', 'http://www.wikidata.org/prop/direct/P156'), ('pName', 'followed by')]
# [('p', 'http://www.wikidata.org/prop/direct/P17'), ('pName', 'country')]
# [('p', 'http://www.wikidata.org/prop/direct/P18'), ('pName', 'image')]
# [('p', 'http://www.wikidata.org/prop/direct/P2094'), ('pName', 'competition class')]
# [('p', 'http://www.wikidata.org/prop/direct/P2581'), ('pName', 'BabelNet ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2671'), ('pName', 'Google Knowledge Graph ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('p', 'http://www.wikidata.org/prop/direct/P361'), ('pName', 'part of')]
# [('p', 'http://www.wikidata.org/prop/direct/P393'), ('pName', 'edition number')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part')]
# [('p', 'http://www.wikidata.org/prop/direct/P585'), ('pName', 'point in time')]
# [('p', 'http://www.wikidata.org/prop/direct/P641'), ('pName', 'sport')]
# [('p', 'http://www.wikidata.org/prop/direct/P646'), ('pName', 'Freebase ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P710'), ('pName', 'participant')]
# [('p', 'http://www.wikidata.org/prop/direct/P276'), ('pName', 'location')]
# [('p', 'http://www.wikidata.org/prop/direct/P580'), ('pName', 'start time')]
# [('p', 'http://www.wikidata.org/prop/direct/P582'), ('pName', 'end time')]
# [('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity')]
# [('p', 'http://www.wikidata.org/prop/direct/P3967'), ('pName', 'final event')]
# [('p', 'http://www.wikidata.org/prop/direct/P373'), ('pName', 'Commons category')]
# [('p', 'http://www.wikidata.org/prop/direct/P3085'), ('pName', 'qualifies for event')]
# [('p', 'http://www.wikidata.org/prop/direct/P1552'), ('pName', 'has quality')]
# [('p', 'http://www.wikidata.org/prop/direct/P2670'), ('pName', 'has parts of the class')]
# 27

# %%
# write your queries
# Consider the country for sport property of the tennis player (NO Country of citizenship). 
# Return the countries with at least one player who won at least one edition of each Grand Slam (the result set must be a list of country IRI and label).

# [('p', 'http://www.wikidata.org/prop/direct/P1532'), ('name', 'country for sport')]

# P31 ('instance of')
# P527 ('has part')
# P1346 ('winner')
# P393 ('edition number')

#[('obj', 'http://www.wikidata.org/entity/Q43605'), ('objName', 'French Open')]
#[('obj', 'http://www.wikidata.org/entity/Q123577'), ('objName', 'US Open')]
#[('obj', 'http://www.wikidata.org/entity/Q41520'), ('objName', 'Wimbledon Championships')]
#[('obj', 'http://www.wikidata.org/entity/Q60874'), ('objName', 'Australian Open')]

# finding ways to group all four tournament by year

queryString = """

PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
SELECT ?obj
WHERE {
   VALUES (?tournament){
       (wd:Q43605)
       (wd:Q123577)
       (wd:Q41520)
       (wd:Q60874)
   }
   # ?yearlyTournament wdt:P31 ?tournament.
   # ?yearlyTournament wdt:P527 ?subTournament.
   # ?subTournament wdt:P393 ?obj.
   
   # get the label 
   # ?yearlyTournament sc:name ?yearlyTournamentName .
   # ?subTournament sc:name ?subTournamentName.
}
ORDER BY DESC (?obj)
LIMIT 50

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('obj', '99')]
# [('obj', '98')]
# [('obj', '97')]
# [('obj', '96')]
# [('obj', '95')]
# [('obj', '94')]
# [('obj', '94')]
# [('obj', '93')]
# [('obj', '92')]
# [('obj', '91')]
# [('obj', '90')]
# [('obj', '90')]
# [('obj', '89')]
# [('obj', '88')]
# [('obj', '88')]
# [('obj', '87')]
# [('obj', '87')]
# [('obj', '86')]
# [('obj', '86')]
# [('obj', '85')]
# [('obj', '84')]
# [('obj', '83')]
# [('obj', '82')]
# [('obj', '81')]
# [('obj', '80')]
# [('obj', '79')]
# [('obj', '78')]
# [('obj', '77')]
# [('obj', '76')]
# [('obj', '75')]
# [('obj', '74')]
# [('obj', '73')]
# [('obj', '72')]
# [('obj', '71')]
# [('obj', '70')]
# [('obj', '67')]
# [('obj', '67')]
# [('obj', '66')]
# [('obj', '65')]
# [('obj', '62')]
# [('obj', '62')]
# [('obj', '61')]
# [('obj', '140')]
# [('obj', '113')]
# [('obj', '112')]
# [('obj', '111')]
# [('obj', '110')]
# [('obj', '109')]
# [('obj', '108')]
# [('obj', '107')]
# 50

# %%
# write your queries
# Consider the country for sport property of the tennis player (NO Country of citizenship). 
# Return the countries with at least one player who won at least one edition of each Grand Slam (the result set must be a list of country IRI and label).

# [('p', 'http://www.wikidata.org/prop/direct/P1532'), ('name', 'country for sport')]

# P31 ('instance of')
# P527 ('has part')
# P1346 ('winner')
# P393 ('edition number')

#[('obj', 'http://www.wikidata.org/entity/Q43605'), ('objName', 'French Open')]
#[('obj', 'http://www.wikidata.org/entity/Q123577'), ('objName', 'US Open')]
#[('obj', 'http://www.wikidata.org/entity/Q41520'), ('objName', 'Wimbledon Championships')]
#[('obj', 'http://www.wikidata.org/entity/Q60874'), ('objName', 'Australian Open')]

# finding ways to group all four tournament by year

queryString = """

PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
SELECT ?subTournament ?obj
WHERE {
   VALUES (?tournament){
       (wd:Q43605)
       (wd:Q123577)
       (wd:Q41520)
       (wd:Q60874)
   }
   # ?yearlyTournament wdt:P31 ?tournament.
   # ?yearlyTournament wdt:P527 ?subTournament.
   # ?subTournament wdt:P393 ?obj.
   
   # get the label 
   # ?yearlyTournament sc:name ?yearlyTournamentName .
   # ?subTournament sc:name ?subTournamentName.
}
ORDER BY DESC (xsd:integer(?obj))
LIMIT 50

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('subTournament', 'http://www.wikidata.org/entity/Q98754894'), ('obj', '140')]
# [('subTournament', 'http://www.wikidata.org/entity/Q63367916'), ('obj', '113')]
# [('subTournament', 'http://www.wikidata.org/entity/Q54197647'), ('obj', '112')]
# [('subTournament', 'http://www.wikidata.org/entity/Q30098117'), ('obj', '111')]
# [('subTournament', 'http://www.wikidata.org/entity/Q24387157'), ('obj', '110')]
# [('subTournament', 'http://www.wikidata.org/entity/Q23892528'), ('obj', '109')]
# [('subTournament', 'http://www.wikidata.org/entity/Q19868605'), ('obj', '108')]
# [('subTournament', 'http://www.wikidata.org/entity/Q16744720'), ('obj', '107')]
# [('subTournament', 'http://www.wikidata.org/entity/Q4629371'), ('obj', '106')]
# [('subTournament', 'http://www.wikidata.org/entity/Q369095'), ('obj', '105')]
# [('subTournament', 'http://www.wikidata.org/entity/Q734804'), ('obj', '104')]
# [('subTournament', 'http://www.wikidata.org/entity/Q832169'), ('obj', '103')]
# [('subTournament', 'http://www.wikidata.org/entity/Q201269'), ('obj', '102')]
# [('subTournament', 'http://www.wikidata.org/entity/Q734321'), ('obj', '101')]
# [('subTournament', 'http://www.wikidata.org/entity/Q899808'), ('obj', '100')]
# [('subTournament', 'http://www.wikidata.org/entity/Q763253'), ('obj', '99')]
# [('subTournament', 'http://www.wikidata.org/entity/Q1068828'), ('obj', '98')]
# [('subTournament', 'http://www.wikidata.org/entity/Q1085849'), ('obj', '97')]
# [('subTournament', 'http://www.wikidata.org/entity/Q1194096'), ('obj', '96')]
# [('subTournament', 'http://www.wikidata.org/entity/Q1068819'), ('obj', '95')]
# [('subTournament', 'http://www.wikidata.org/entity/Q258090'), ('obj', '94')]
# [('subTournament', 'http://www.wikidata.org/entity/Q383697'), ('obj', '94')]
# [('subTournament', 'http://www.wikidata.org/entity/Q1068835'), ('obj', '93')]
# [('subTournament', 'http://www.wikidata.org/entity/Q145174'), ('obj', '92')]
# [('subTournament', 'http://www.wikidata.org/entity/Q932488'), ('obj', '91')]
# [('subTournament', 'http://www.wikidata.org/entity/Q1081089'), ('obj', '90')]
# [('subTournament', 'http://www.wikidata.org/entity/Q532931'), ('obj', '90')]
# [('subTournament', 'http://www.wikidata.org/entity/Q660734'), ('obj', '89')]
# [('subTournament', 'http://www.wikidata.org/entity/Q513433'), ('obj', '88')]
# [('subTournament', 'http://www.wikidata.org/entity/Q1059705'), ('obj', '88')]
# [('subTournament', 'http://www.wikidata.org/entity/Q531143'), ('obj', '87')]
# [('subTournament', 'http://www.wikidata.org/entity/Q535125'), ('obj', '87')]
# [('subTournament', 'http://www.wikidata.org/entity/Q943066'), ('obj', '86')]
# [('subTournament', 'http://www.wikidata.org/entity/Q1059596'), ('obj', '86')]
# [('subTournament', 'http://www.wikidata.org/entity/Q943266'), ('obj', '85')]
# [('subTournament', 'http://www.wikidata.org/entity/Q1059665'), ('obj', '84')]
# [('subTournament', 'http://www.wikidata.org/entity/Q925574'), ('obj', '83')]
# [('subTournament', 'http://www.wikidata.org/entity/Q1059603'), ('obj', '82')]
# [('subTournament', 'http://www.wikidata.org/entity/Q598630'), ('obj', '81')]
# [('subTournament', 'http://www.wikidata.org/entity/Q1060429'), ('obj', '80')]
# [('subTournament', 'http://www.wikidata.org/entity/Q1059700'), ('obj', '79')]
# [('subTournament', 'http://www.wikidata.org/entity/Q730174'), ('obj', '78')]
# [('subTournament', 'http://www.wikidata.org/entity/Q385554'), ('obj', '77')]
# [('subTournament', 'http://www.wikidata.org/entity/Q1059712'), ('obj', '76')]
# [('subTournament', 'http://www.wikidata.org/entity/Q600534'), ('obj', '75')]
# [('subTournament', 'http://www.wikidata.org/entity/Q429386'), ('obj', '74')]
# [('subTournament', 'http://www.wikidata.org/entity/Q925347'), ('obj', '73')]
# [('subTournament', 'http://www.wikidata.org/entity/Q1060420'), ('obj', '72')]
# [('subTournament', 'http://www.wikidata.org/entity/Q1059726'), ('obj', '71')]
# [('subTournament', 'http://www.wikidata.org/entity/Q1059719'), ('obj', '70')]
# 50

# %%
# write your queries
# Consider the country for sport property of the tennis player (NO Country of citizenship). 
# Return the countries with at least one player who won at least one edition of each Grand Slam (the result set must be a list of country IRI and label).

# [('p', 'http://www.wikidata.org/prop/direct/P1532'), ('name', 'country for sport')]

# P31 ('instance of')
# P527 ('has part')
# P1346 ('winner')
# P393 ('edition number')

#[('obj', 'http://www.wikidata.org/entity/Q43605'), ('objName', 'French Open')]
#[('obj', 'http://www.wikidata.org/entity/Q123577'), ('objName', 'US Open')]
#[('obj', 'http://www.wikidata.org/entity/Q41520'), ('objName', 'Wimbledon Championships')]
#[('obj', 'http://www.wikidata.org/entity/Q60874'), ('objName', 'Australian Open')]

# finding ways to group all four tournament by year

queryString = """

PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
SELECT ?subTournament ?subTournamentName ?obj
WHERE {
   VALUES (?tournament){
       (wd:Q43605)
       (wd:Q123577)
       (wd:Q41520)
       (wd:Q60874)
   }
   # ?yearlyTournament wdt:P31 ?tournament.
   # ?yearlyTournament wdt:P527 ?subTournament.
   # ?subTournament wdt:P393 ?obj.
   
   # get the label 
   # ?yearlyTournament sc:name ?yearlyTournamentName .
   # ?subTournament sc:name ?subTournamentName.
}
ORDER BY DESC (xsd:integer(?obj))
LIMIT 20

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('subTournament', 'http://www.wikidata.org/entity/Q98754894'), ('subTournamentName', "2020 US Open – Men's Doubles"), ('obj', '140')]
# [('subTournament', 'http://www.wikidata.org/entity/Q63367916'), ('subTournamentName', "2020 French Open – Women's Singles"), ('obj', '113')]
# [('subTournament', 'http://www.wikidata.org/entity/Q54197647'), ('subTournamentName', "2019 French Open – Women's Singles"), ('obj', '112')]
# [('subTournament', 'http://www.wikidata.org/entity/Q30098117'), ('subTournamentName', "2018 French Open – Women's Singles"), ('obj', '111')]
# [('subTournament', 'http://www.wikidata.org/entity/Q24387157'), ('subTournamentName', "2017 French Open – Women's Singles"), ('obj', '110')]
# [('subTournament', 'http://www.wikidata.org/entity/Q23892528'), ('subTournamentName', "2016 French Open – Women's Singles"), ('obj', '109')]
# [('subTournament', 'http://www.wikidata.org/entity/Q19868605'), ('subTournamentName', "2015 French Open – Women's Singles"), ('obj', '108')]
# [('subTournament', 'http://www.wikidata.org/entity/Q16744720'), ('subTournamentName', "2014 French Open – Women's Singles"), ('obj', '107')]
# [('subTournament', 'http://www.wikidata.org/entity/Q4629371'), ('subTournamentName', "2013 French Open – Women's Singles"), ('obj', '106')]
# [('subTournament', 'http://www.wikidata.org/entity/Q369095'), ('subTournamentName', "2012 French Open – Women's Singles"), ('obj', '105')]
# [('subTournament', 'http://www.wikidata.org/entity/Q734804'), ('subTournamentName', "2011 French Open – Women's Singles"), ('obj', '104')]
# [('subTournament', 'http://www.wikidata.org/entity/Q832169'), ('subTournamentName', "2010 French Open – Women's Singles"), ('obj', '103')]
# [('subTournament', 'http://www.wikidata.org/entity/Q201269'), ('subTournamentName', "2009 French Open – Women's Singles"), ('obj', '102')]
# [('subTournament', 'http://www.wikidata.org/entity/Q734321'), ('subTournamentName', "2008 French Open – Women's Singles"), ('obj', '101')]
# [('subTournament', 'http://www.wikidata.org/entity/Q899808'), ('subTournamentName', "2007 French Open – Women's Singles"), ('obj', '100')]
# [('subTournament', 'http://www.wikidata.org/entity/Q763253'), ('subTournamentName', "2006 French Open – Women's Singles"), ('obj', '99')]
# [('subTournament', 'http://www.wikidata.org/entity/Q1068828'), ('subTournamentName', "2005 French Open – Women's Singles"), ('obj', '98')]
# [('subTournament', 'http://www.wikidata.org/entity/Q1085849'), ('subTournamentName', "2004 French Open – Women's Singles"), ('obj', '97')]
# [('subTournament', 'http://www.wikidata.org/entity/Q1194096'), ('subTournamentName', "2003 French Open – Women's Singles"), ('obj', '96')]
# [('subTournament', 'http://www.wikidata.org/entity/Q1068819'), ('subTournamentName', "2002 French Open – Women's Singles"), ('obj', '95')]
# 20

# %%
# write your queries
# Consider the country for sport property of the tennis player (NO Country of citizenship). 
# Return the countries with at least one player who won at least one edition of each Grand Slam (the result set must be a list of country IRI and label).

# [('p', 'http://www.wikidata.org/prop/direct/P1532'), ('name', 'country for sport')]

# P31 ('instance of')
# P527 ('has part')
# P1346 ('winner')
# P393 ('edition number')

#[('obj', 'http://www.wikidata.org/entity/Q43605'), ('objName', 'French Open')]
#[('obj', 'http://www.wikidata.org/entity/Q123577'), ('objName', 'US Open')]
#[('obj', 'http://www.wikidata.org/entity/Q41520'), ('objName', 'Wimbledon Championships')]
#[('obj', 'http://www.wikidata.org/entity/Q60874'), ('objName', 'Australian Open')]

# finding ways to group all four tournament by year

queryString = """

PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
SELECT (COUNT(*) as ?totWithEditionNumber)
WHERE {
   VALUES (?tournament){
       (wd:Q43605)
       (wd:Q123577)
       (wd:Q41520)
       (wd:Q60874)
   }
   # ?yearlyTournament wdt:P31 ?tournament.
   # ?yearlyTournament wdt:P527 ?subTournament.
   # ?subTournament wdt:P393 ?obj.
   
   # get the label 
   # ?yearlyTournament sc:name ?yearlyTournamentName .
   # ?subTournament sc:name ?subTournamentName.
}
LIMIT 20

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('totWithEditionNumber', '57')]
# 1

# %%
# write your queries
# Consider the country for sport property of the tennis player (NO Country of citizenship). 
# Return the countries with at least one player who won at least one edition of each Grand Slam (the result set must be a list of country IRI and label).

# [('p', 'http://www.wikidata.org/prop/direct/P1532'), ('name', 'country for sport')]

# P31 ('instance of')
# P527 ('has part')
# P1346 ('winner')
# P393 ('edition number')

#[('obj', 'http://www.wikidata.org/entity/Q43605'), ('objName', 'French Open')]
#[('obj', 'http://www.wikidata.org/entity/Q123577'), ('objName', 'US Open')]
#[('obj', 'http://www.wikidata.org/entity/Q41520'), ('objName', 'Wimbledon Championships')]
#[('obj', 'http://www.wikidata.org/entity/Q60874'), ('objName', 'Australian Open')]

# finding ways to group all four tournament by year

queryString = """

PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
SELECT (COUNT(*) as ?totWithoutEditionNumber)
WHERE {
   VALUES (?tournament){
       (wd:Q43605)
       (wd:Q123577)
       (wd:Q41520)
       (wd:Q60874)
   }
   # ?yearlyTournament wdt:P31 ?tournament.
   # ?yearlyTournament wdt:P527 ?subTournament.
   # ?subTournament wdt:P1346 ?obj.
   
   # get the label 
   # ?yearlyTournament sc:name ?yearlyTournamentName .
   # ?subTournament sc:name ?subTournamentName.
}
LIMIT 20

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('totWithoutEditionNumber', '1809')]
# 1

# %%
# write your queries
# Consider the country for sport property of the tennis player (NO Country of citizenship). 
# Return the countries with at least one player who won at least one edition of each Grand Slam (the result set must be a list of country IRI and label).

# [('p', 'http://www.wikidata.org/prop/direct/P1532'), ('name', 'country for sport')]

# P31 ('instance of')
# P527 ('has part')
# P1346 ('winner')
# P393 ('edition number')

#[('obj', 'http://www.wikidata.org/entity/Q43605'), ('objName', 'French Open')]
#[('obj', 'http://www.wikidata.org/entity/Q123577'), ('objName', 'US Open')]
#[('obj', 'http://www.wikidata.org/entity/Q41520'), ('objName', 'Wimbledon Championships')]
#[('obj', 'http://www.wikidata.org/entity/Q60874'), ('objName', 'Australian Open')]

# finding ways to group all four tournament by year

queryString = """

PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
SELECT ?subTournament ?subTournamentName ?obj
WHERE {
   VALUES (?tournament){
       (wd:Q43605)
       (wd:Q123577)
       (wd:Q41520)
       (wd:Q60874)
   }
   # ?yearlyTournament wdt:P31 ?tournament.
   # ?yearlyTournament wdt:P527 ?subTournament.
   # ?subTournament wdt:P393 ?obj.
   
   # get the label 
   # ?yearlyTournament sc:name ?yearlyTournamentName .
   # ?subTournament sc:name ?subTournamentName.
}
ORDER BY DESC (xsd:integer(?obj))
LIMIT 100

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('subTournament', 'http://www.wikidata.org/entity/Q98754894'), ('subTournamentName', "2020 US Open – Men's Doubles"), ('obj', '140')]
# [('subTournament', 'http://www.wikidata.org/entity/Q63367916'), ('subTournamentName', "2020 French Open – Women's Singles"), ('obj', '113')]
# [('subTournament', 'http://www.wikidata.org/entity/Q54197647'), ('subTournamentName', "2019 French Open – Women's Singles"), ('obj', '112')]
# [('subTournament', 'http://www.wikidata.org/entity/Q30098117'), ('subTournamentName', "2018 French Open – Women's Singles"), ('obj', '111')]
# [('subTournament', 'http://www.wikidata.org/entity/Q24387157'), ('subTournamentName', "2017 French Open – Women's Singles"), ('obj', '110')]
# [('subTournament', 'http://www.wikidata.org/entity/Q23892528'), ('subTournamentName', "2016 French Open – Women's Singles"), ('obj', '109')]
# [('subTournament', 'http://www.wikidata.org/entity/Q19868605'), ('subTournamentName', "2015 French Open – Women's Singles"), ('obj', '108')]
# [('subTournament', 'http://www.wikidata.org/entity/Q16744720'), ('subTournamentName', "2014 French Open – Women's Singles"), ('obj', '107')]
# [('subTournament', 'http://www.wikidata.org/entity/Q4629371'), ('subTournamentName', "2013 French Open – Women's Singles"), ('obj', '106')]
# [('subTournament', 'http://www.wikidata.org/entity/Q369095'), ('subTournamentName', "2012 French Open – Women's Singles"), ('obj', '105')]
# [('subTournament', 'http://www.wikidata.org/entity/Q734804'), ('subTournamentName', "2011 French Open – Women's Singles"), ('obj', '104')]
# [('subTournament', 'http://www.wikidata.org/entity/Q832169'), ('subTournamentName', "2010 French Open – Women's Singles"), ('obj', '103')]
# [('subTournament', 'http://www.wikidata.org/entity/Q201269'), ('subTournamentName', "2009 French Open – Women's Singles"), ('obj', '102')]
# [('subTournament', 'http://www.wikidata.org/entity/Q734321'), ('subTournamentName', "2008 French Open – Women's Singles"), ('obj', '101')]
# [('subTournament', 'http://www.wikidata.org/entity/Q899808'), ('subTournamentName', "2007 French Open – Women's Singles"), ('obj', '100')]
# [('subTournament', 'http://www.wikidata.org/entity/Q763253'), ('subTournamentName', "2006 French Open – Women's Singles"), ('obj', '99')]
# [('subTournament', 'http://www.wikidata.org/entity/Q1068828'), ('subTournamentName', "2005 French Open – Women's Singles"), ('obj', '98')]
# [('subTournament', 'http://www.wikidata.org/entity/Q1085849'), ('subTournamentName', "2004 French Open – Women's Singles"), ('obj', '97')]
# [('subTournament', 'http://www.wikidata.org/entity/Q1194096'), ('subTournamentName', "2003 French Open – Women's Singles"), ('obj', '96')]
# [('subTournament', 'http://www.wikidata.org/entity/Q1068819'), ('subTournamentName', "2002 French Open – Women's Singles"), ('obj', '95')]
# [('subTournament', 'http://www.wikidata.org/entity/Q258090'), ('subTournamentName', "1995 French Open – Men's Singles"), ('obj', '94')]
# [('subTournament', 'http://www.wikidata.org/entity/Q383697'), ('subTournamentName', "2001 French Open – Women's Singles"), ('obj', '94')]
# [('subTournament', 'http://www.wikidata.org/entity/Q1068835'), ('subTournamentName', "2000 French Open – Women's Singles"), ('obj', '93')]
# [('subTournament', 'http://www.wikidata.org/entity/Q145174'), ('subTournamentName', "1999 French Open – Women's Singles"), ('obj', '92')]
# [('subTournament', 'http://www.wikidata.org/entity/Q932488'), ('subTournamentName', "1998 French Open – Women's Singles"), ('obj', '91')]
# [('subTournament', 'http://www.wikidata.org/entity/Q1081089'), ('subTournamentName', "1997 French Open – Women's Singles"), ('obj', '90')]
# [('subTournament', 'http://www.wikidata.org/entity/Q532931'), ('subTournamentName', "1991 French Open – Men's Singles"), ('obj', '90')]
# [('subTournament', 'http://www.wikidata.org/entity/Q660734'), ('subTournamentName', "1996 French Open – Women's Singles"), ('obj', '89')]
# [('subTournament', 'http://www.wikidata.org/entity/Q513433'), ('subTournamentName', "1989 French Open – Men's Singles"), ('obj', '88')]
# [('subTournament', 'http://www.wikidata.org/entity/Q1059705'), ('subTournamentName', "1995 French Open – Women's Singles"), ('obj', '88')]
# [('subTournament', 'http://www.wikidata.org/entity/Q531143'), ('subTournamentName', "1988 French Open – Men's Singles"), ('obj', '87')]
# [('subTournament', 'http://www.wikidata.org/entity/Q535125'), ('subTournamentName', "1994 French Open – Women's Singles"), ('obj', '87')]
# [('subTournament', 'http://www.wikidata.org/entity/Q943066'), ('subTournamentName', "1987 French Open – Men's Singles"), ('obj', '86')]
# [('subTournament', 'http://www.wikidata.org/entity/Q1059596'), ('subTournamentName', "1993 French Open – Women's Singles"), ('obj', '86')]
# [('subTournament', 'http://www.wikidata.org/entity/Q943266'), ('subTournamentName', "1992 French Open – Women's Singles"), ('obj', '85')]
# [('subTournament', 'http://www.wikidata.org/entity/Q1059665'), ('subTournamentName', "1991 French Open – Women's Singles"), ('obj', '84')]
# [('subTournament', 'http://www.wikidata.org/entity/Q925574'), ('subTournamentName', "1990 French Open – Women's Singles"), ('obj', '83')]
# [('subTournament', 'http://www.wikidata.org/entity/Q1059603'), ('subTournamentName', "1989 French Open – Women's Singles"), ('obj', '82')]
# [('subTournament', 'http://www.wikidata.org/entity/Q598630'), ('subTournamentName', "1988 French Open – Women's Singles"), ('obj', '81')]
# [('subTournament', 'http://www.wikidata.org/entity/Q1060429'), ('subTournamentName', "1987 French Open – Women's Singles"), ('obj', '80')]
# [('subTournament', 'http://www.wikidata.org/entity/Q1059700'), ('subTournamentName', "1986 French Open – Women's Singles"), ('obj', '79')]
# [('subTournament', 'http://www.wikidata.org/entity/Q730174'), ('subTournamentName', "1985 French Open – Women's Singles"), ('obj', '78')]
# [('subTournament', 'http://www.wikidata.org/entity/Q385554'), ('subTournamentName', "1984 French Open – Women's Singles"), ('obj', '77')]
# [('subTournament', 'http://www.wikidata.org/entity/Q1059712'), ('subTournamentName', "1983 French Open – Women's Singles"), ('obj', '76')]
# [('subTournament', 'http://www.wikidata.org/entity/Q600534'), ('subTournamentName', "1982 French Open – Women's Singles"), ('obj', '75')]
# [('subTournament', 'http://www.wikidata.org/entity/Q429386'), ('subTournamentName', "1981 French Open – women's singles"), ('obj', '74')]
# [('subTournament', 'http://www.wikidata.org/entity/Q925347'), ('subTournamentName', "1980 French Open – Women's Singles"), ('obj', '73')]
# [('subTournament', 'http://www.wikidata.org/entity/Q1060420'), ('subTournamentName', "1979 French Open – Women's Singles"), ('obj', '72')]
# [('subTournament', 'http://www.wikidata.org/entity/Q1059726'), ('subTournamentName', "1978 French Open – Women's Singles"), ('obj', '71')]
# [('subTournament', 'http://www.wikidata.org/entity/Q1059719'), ('subTournamentName', "1977 French Open – Women's Singles"), ('obj', '70')]
# [('subTournament', 'http://www.wikidata.org/entity/Q799562'), ('subTournamentName', "1960 Wimbledon Championships – Women's Singles"), ('obj', '67')]
# [('subTournament', 'http://www.wikidata.org/entity/Q1455345'), ('subTournamentName', "1974 French Open – Women's Singles"), ('obj', '67')]
# [('subTournament', 'http://www.wikidata.org/entity/Q1455342'), ('subTournamentName', "1973 French Open – Women's Singles"), ('obj', '66')]
# [('subTournament', 'http://www.wikidata.org/entity/Q580711'), ('subTournamentName', "1972 French Open – Women's Singles"), ('obj', '65')]
# [('subTournament', 'http://www.wikidata.org/entity/Q655025'), ('subTournamentName', "1955 Wimbledon Championships – Women's Singles"), ('obj', '62')]
# [('subTournament', 'http://www.wikidata.org/entity/Q594977'), ('subTournamentName', "1969 French Open – Women's Singles"), ('obj', '62')]
# [('subTournament', 'http://www.wikidata.org/entity/Q963544'), ('subTournamentName', "1968 French Open – Women's Singles"), ('obj', '61')]
# 57

# %% [markdown]
# ##### Can't use edition number P393, only 57 has this field

# %%
# write your queries
# Consider the country for sport property of the tennis player (NO Country of citizenship). 
# Return the countries with at least one player who won at least one edition of each Grand Slam (the result set must be a list of country IRI and label).

# [('p', 'http://www.wikidata.org/prop/direct/P1532'), ('name', 'country for sport')]

# P31 ('instance of')
# P527 ('has part')
# P1346 ('winner')

#[('obj', 'http://www.wikidata.org/entity/Q43605'), ('objName', 'French Open')]
#[('obj', 'http://www.wikidata.org/entity/Q123577'), ('objName', 'US Open')]
#[('obj', 'http://www.wikidata.org/entity/Q41520'), ('objName', 'Wimbledon Championships')]
#[('obj', 'http://www.wikidata.org/entity/Q60874'), ('objName', 'Australian Open')]

# finding ways to group all four tournament by year

queryString = """

PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
SELECT DISTINCT ?p ?pName
WHERE {
   VALUES (?tournament){
       (wd:Q43605)
       (wd:Q123577)
       (wd:Q41520)
       (wd:Q60874)
   }
   # ?s ?p ?tournament.
   #?tournament ?direct ?o.  
   # ?p sc:name ?pName.
}
LIMIT 50

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P1423'), ('pName', 'template has topic')]
# [('p', 'http://www.wikidata.org/prop/direct/P1269'), ('pName', 'facet of')]
# [('p', 'http://www.wikidata.org/prop/direct/P1344'), ('pName', 'participant in')]
# [('p', 'http://www.wikidata.org/prop/direct/P138'), ('pName', 'named after')]
# [('p', 'http://www.wikidata.org/prop/direct/P1889'), ('pName', 'different from')]
# [('p', 'http://www.wikidata.org/prop/direct/P2522'), ('pName', 'victory')]
# [('p', 'http://www.wikidata.org/prop/direct/P301'), ('pName', "category's main topic")]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('p', 'http://www.wikidata.org/prop/direct/P3450'), ('pName', 'sports season of league or competition')]
# [('p', 'http://www.wikidata.org/prop/direct/P361'), ('pName', 'part of')]
# [('p', 'http://www.wikidata.org/prop/direct/P466'), ('pName', 'occupant')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part')]
# [('p', 'http://www.wikidata.org/prop/direct/P710'), ('pName', 'participant')]
# [('p', 'http://www.wikidata.org/prop/direct/P971'), ('pName', 'category combines topics')]
# [('p', 'http://www.wikidata.org/prop/direct/P1629'), ('pName', 'Wikidata item of this property')]
# [('p', 'http://www.wikidata.org/prop/direct/P1855'), ('pName', 'Wikidata property example')]
# 16

# %%
# write your queries
# Consider the country for sport property of the tennis player (NO Country of citizenship). 
# Return the countries with at least one player who won at least one edition of each Grand Slam (the result set must be a list of country IRI and label).

# [('p', 'http://www.wikidata.org/prop/direct/P1532'), ('name', 'country for sport')]

# P31 ('instance of')
# P527 ('has part')
# P1346 ('winner')

#[('obj', 'http://www.wikidata.org/entity/Q43605'), ('objName', 'French Open')]
#[('obj', 'http://www.wikidata.org/entity/Q123577'), ('objName', 'US Open')]
#[('obj', 'http://www.wikidata.org/entity/Q41520'), ('objName', 'Wimbledon Championships')]
#[('obj', 'http://www.wikidata.org/entity/Q60874'), ('objName', 'Australian Open')]

# finding ways to group all four tournament by year

queryString = """

PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
SELECT DISTINCT ?p ?pName
WHERE {
   VALUES (?tournament){
       (wd:Q43605)
       (wd:Q123577)
       (wd:Q41520)
       (wd:Q60874)
   }
   #?s ?p ?tournament.
   # ?tournament ?p ?o.  
   # ?p sc:name ?pName.
}
LIMIT 50

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P1296'), ('pName', 'Gran Enciclopèdia Catalana ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity')]
# [('p', 'http://www.wikidata.org/prop/direct/P138'), ('pName', 'named after')]
# [('p', 'http://www.wikidata.org/prop/direct/P1417'), ('pName', 'Encyclopædia Britannica Online ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1424'), ('pName', "topic's main template")]
# [('p', 'http://www.wikidata.org/prop/direct/P154'), ('pName', 'logo image')]
# [('p', 'http://www.wikidata.org/prop/direct/P1687'), ('pName', 'Wikidata property')]
# [('p', 'http://www.wikidata.org/prop/direct/P17'), ('pName', 'country')]
# [('p', 'http://www.wikidata.org/prop/direct/P18'), ('pName', 'image')]
# [('p', 'http://www.wikidata.org/prop/direct/P1814'), ('pName', 'name in kana')]
# [('p', 'http://www.wikidata.org/prop/direct/P1889'), ('pName', 'different from')]
# [('p', 'http://www.wikidata.org/prop/direct/P2002'), ('pName', 'Twitter username')]
# [('p', 'http://www.wikidata.org/prop/direct/P2003'), ('pName', 'Instagram username')]
# [('p', 'http://www.wikidata.org/prop/direct/P2013'), ('pName', 'Facebook ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2121'), ('pName', 'prize money')]
# [('p', 'http://www.wikidata.org/prop/direct/P214'), ('pName', 'VIAF ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2184'), ('pName', 'history of topic')]
# [('p', 'http://www.wikidata.org/prop/direct/P2257'), ('pName', 'event interval')]
# [('p', 'http://www.wikidata.org/prop/direct/P227'), ('pName', 'GND ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2354'), ('pName', 'has list')]
# [('p', 'http://www.wikidata.org/prop/direct/P2397'), ('pName', 'YouTube channel ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P244'), ('pName', 'Library of Congress authority ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P276'), ('pName', 'location')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of')]
# [('p', 'http://www.wikidata.org/prop/direct/P2924'), ('pName', 'Great Russian Encyclopedia Online ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('p', 'http://www.wikidata.org/prop/direct/P3221'), ('pName', 'New York Times topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3414'), ('pName', 'Yle Areena item ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3417'), ('pName', 'Quora topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3479'), ('pName', 'Omni topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3509'), ('pName', 'Dagens Nyheter topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3553'), ('pName', 'Zhihu topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P361'), ('pName', 'part of')]
# [('p', 'http://www.wikidata.org/prop/direct/P373'), ('pName', 'Commons category')]
# [('p', 'http://www.wikidata.org/prop/direct/P4013'), ('pName', 'Giphy username')]
# [('p', 'http://www.wikidata.org/prop/direct/P4431'), ('pName', 'Google Doodle')]
# [('p', 'http://www.wikidata.org/prop/direct/P4622'), ('pName', 'trophy awarded')]
# [('p', 'http://www.wikidata.org/prop/direct/P4794'), ('pName', 'season starts')]
# [('p', 'http://www.wikidata.org/prop/direct/P571'), ('pName', 'inception')]
# [('p', 'http://www.wikidata.org/prop/direct/P641'), ('pName', 'sport')]
# [('p', 'http://www.wikidata.org/prop/direct/P646'), ('pName', 'Freebase ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P664'), ('pName', 'organizer')]
# [('p', 'http://www.wikidata.org/prop/direct/P6849'), ('pName', 'DR topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P691'), ('pName', 'NKCR AUT ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P765'), ('pName', 'surface played on')]
# [('p', 'http://www.wikidata.org/prop/direct/P7818'), ('pName', 'French Vikidia ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7859'), ('pName', 'WorldCat Identities ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7959'), ('pName', 'historic county')]
# [('p', 'http://www.wikidata.org/prop/direct/P8408'), ('pName', 'KBpedia ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P856'), ('pName', 'official website')]
# 50

# %%
# write your queries
# Consider the country for sport property of the tennis player (NO Country of citizenship). 
# Return the countries with at least one player who won at least one edition of each Grand Slam (the result set must be a list of country IRI and label).

# [('p', 'http://www.wikidata.org/prop/direct/P1532'), ('name', 'country for sport')]

# P31 ('instance of')
# P527 ('has part')
# P1346 ('winner')

#[('obj', 'http://www.wikidata.org/entity/Q43605'), ('objName', 'French Open')]
#[('obj', 'http://www.wikidata.org/entity/Q123577'), ('objName', 'US Open')]
#[('obj', 'http://www.wikidata.org/entity/Q41520'), ('objName', 'Wimbledon Championships')]
#[('obj', 'http://www.wikidata.org/entity/Q60874'), ('objName', 'Australian Open')]

# finding ways to group all four tournament by year

queryString = """

PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
SELECT DISTINCT ?instance ?name
WHERE {
   VALUES (?tournament){
       (wd:Q43605)
       (wd:Q123577)
       (wd:Q41520)
       (wd:Q60874)
   }
   # ?instance wdt:P31 ?tournament.
   # ?instance sc:name ?name.
}
LIMIT 100

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('instance', 'http://www.wikidata.org/entity/Q268871'), ('name', '2004 Wimbledon Championships')]
# [('instance', 'http://www.wikidata.org/entity/Q602116'), ('name', '1969 Australian Open')]
# [('instance', 'http://www.wikidata.org/entity/Q643498'), ('name', '2000 US Open')]
# [('instance', 'http://www.wikidata.org/entity/Q660527'), ('name', '1983 French Open')]
# [('instance', 'http://www.wikidata.org/entity/Q840907'), ('name', '2004 US Open')]
# [('instance', 'http://www.wikidata.org/entity/Q846695'), ('name', '2000 French Open')]
# [('instance', 'http://www.wikidata.org/entity/Q173961'), ('name', '1978 Wimbledon Championships')]
# [('instance', 'http://www.wikidata.org/entity/Q925026'), ('name', '1971 Wimbledon Championships')]
# [('instance', 'http://www.wikidata.org/entity/Q776766'), ('name', '1928 French Championships')]
# [('instance', 'http://www.wikidata.org/entity/Q15854765'), ('name', '2014 Wimbledon Championships')]
# [('instance', 'http://www.wikidata.org/entity/Q15851911'), ('name', '2014 US Open')]
# [('instance', 'http://www.wikidata.org/entity/Q2611589'), ('name', '1906 Australasian Championships')]
# [('instance', 'http://www.wikidata.org/entity/Q21521385'), ('name', '2016 Australian Open')]
# [('instance', 'http://www.wikidata.org/entity/Q22077628'), ('name', '2017 Australian Open')]
# [('instance', 'http://www.wikidata.org/entity/Q30085309'), ('name', '2018 Wimbledon Championships')]
# [('instance', 'http://www.wikidata.org/entity/Q174590'), ('name', '1979 French Open')]
# [('instance', 'http://www.wikidata.org/entity/Q2715352'), ('name', '1959 Australian Championships')]
# [('instance', 'http://www.wikidata.org/entity/Q2718193'), ('name', '1957 Australian Championships')]
# [('instance', 'http://www.wikidata.org/entity/Q546356'), ('name', '1980 French Open')]
# [('instance', 'http://www.wikidata.org/entity/Q550332'), ('name', '1958 Australian Championships')]
# [('instance', 'http://www.wikidata.org/entity/Q745901'), ('name', '1974 Wimbledon Championships')]
# [('instance', 'http://www.wikidata.org/entity/Q924070'), ('name', '1981 French Open')]
# [('instance', 'http://www.wikidata.org/entity/Q202226'), ('name', '1969 French Open')]
# [('instance', 'http://www.wikidata.org/entity/Q588389'), ('name', '1975 Australian Open')]
# [('instance', 'http://www.wikidata.org/entity/Q781658'), ('name', '1972 Australian Open')]
# [('instance', 'http://www.wikidata.org/entity/Q781682'), ('name', '1974 Australian Open')]
# [('instance', 'http://www.wikidata.org/entity/Q781718'), ('name', '1976 Australian Open')]
# [('instance', 'http://www.wikidata.org/entity/Q1068990'), ('name', '1971 US Open')]
# [('instance', 'http://www.wikidata.org/entity/Q277655'), ('name', '2008 French Open')]
# [('instance', 'http://www.wikidata.org/entity/Q655368'), ('name', '1955 Wimbledon Championships')]
# [('instance', 'http://www.wikidata.org/entity/Q655378'), ('name', '1956 Wimbledon Championships')]
# [('instance', 'http://www.wikidata.org/entity/Q657950'), ('name', '1957 Wimbledon Championships')]
# [('instance', 'http://www.wikidata.org/entity/Q657962'), ('name', '1958 Wimbledon Championships')]
# [('instance', 'http://www.wikidata.org/entity/Q1752083'), ('name', '1902 French Championships')]
# [('instance', 'http://www.wikidata.org/entity/Q1752087'), ('name', '1901 French Championships')]
# [('instance', 'http://www.wikidata.org/entity/Q2409966'), ('name', '1960 U.S. National Championships')]
# [('instance', 'http://www.wikidata.org/entity/Q2409981'), ('name', '1955 U.S. National Championships')]
# [('instance', 'http://www.wikidata.org/entity/Q2410709'), ('name', '1935 U.S. National Championships')]
# [('instance', 'http://www.wikidata.org/entity/Q2440782'), ('name', '1968 Australian Championships')]
# [('instance', 'http://www.wikidata.org/entity/Q2539662'), ('name', '1938 French Championships')]
# [('instance', 'http://www.wikidata.org/entity/Q2540106'), ('name', '1935 French Championships')]
# [('instance', 'http://www.wikidata.org/entity/Q2718179'), ('name', '1946 Australian Championships')]
# [('instance', 'http://www.wikidata.org/entity/Q2718203'), ('name', '1962 Australian Championships')]
# [('instance', 'http://www.wikidata.org/entity/Q2951379'), ('name', '1900 French Championships')]
# [('instance', 'http://www.wikidata.org/entity/Q507128'), ('name', '1952 French Championships')]
# [('instance', 'http://www.wikidata.org/entity/Q598746'), ('name', '2006 Australian Open')]
# [('instance', 'http://www.wikidata.org/entity/Q962085'), ('name', '1931 Australian Championships')]
# [('instance', 'http://www.wikidata.org/entity/Q2296335'), ('name', '1881 Wimbledon Championship')]
# [('instance', 'http://www.wikidata.org/entity/Q2297185'), ('name', '1882 Wimbledon Championship')]
# [('instance', 'http://www.wikidata.org/entity/Q522860'), ('name', '1883 Wimbledon Championship')]
# [('instance', 'http://www.wikidata.org/entity/Q2539673'), ('name', '1946 French Championships')]
# [('instance', 'http://www.wikidata.org/entity/Q2540136'), ('name', '1951 French Championships')]
# [('instance', 'http://www.wikidata.org/entity/Q2540165'), ('name', '1939 French Championships')]
# [('instance', 'http://www.wikidata.org/entity/Q2548462'), ('name', '1950 French Championships')]
# [('instance', 'http://www.wikidata.org/entity/Q20127632'), ('name', '2016 Wimbledon Championships')]
# [('instance', 'http://www.wikidata.org/entity/Q24480003'), ('name', '2016 US Open')]
# [('instance', 'http://www.wikidata.org/entity/Q24387175'), ('name', '2017 French Open')]
# [('instance', 'http://www.wikidata.org/entity/Q934978'), ('name', '1988 Wimbledon Championships')]
# [('instance', 'http://www.wikidata.org/entity/Q856524'), ('name', '2002 US Open')]
# [('instance', 'http://www.wikidata.org/entity/Q244427'), ('name', '2011 French Open')]
# [('instance', 'http://www.wikidata.org/entity/Q248438'), ('name', '2010 French Open')]
# [('instance', 'http://www.wikidata.org/entity/Q381118'), ('name', '2009 French Open')]
# [('instance', 'http://www.wikidata.org/entity/Q388312'), ('name', '2008 Wimbledon Championships')]
# [('instance', 'http://www.wikidata.org/entity/Q577107'), ('name', '2008 Australian Open')]
# [('instance', 'http://www.wikidata.org/entity/Q756439'), ('name', '2007 US Open')]
# [('instance', 'http://www.wikidata.org/entity/Q1049018'), ('name', '1980 Wimbledon Championships')]
# [('instance', 'http://www.wikidata.org/entity/Q404337'), ('name', '1929 Wimbledon Championships')]
# [('instance', 'http://www.wikidata.org/entity/Q404437'), ('name', '1930 Wimbledon Championships')]
# [('instance', 'http://www.wikidata.org/entity/Q404791'), ('name', '1933 Wimbledon Championships')]
# [('instance', 'http://www.wikidata.org/entity/Q781639'), ('name', '1970 Australian Open')]
# [('instance', 'http://www.wikidata.org/entity/Q330022'), ('name', '2009 Australian Open')]
# [('instance', 'http://www.wikidata.org/entity/Q381132'), ('name', '2011 Australian Open')]
# [('instance', 'http://www.wikidata.org/entity/Q476646'), ('name', '2010 Australian Open')]
# [('instance', 'http://www.wikidata.org/entity/Q855690'), ('name', '1968 Wimbledon Championships')]
# [('instance', 'http://www.wikidata.org/entity/Q924987'), ('name', '1988 French Open')]
# [('instance', 'http://www.wikidata.org/entity/Q577138'), ('name', '1954 Wimbledon Championships')]
# [('instance', 'http://www.wikidata.org/entity/Q244370'), ('name', '2009 Wimbledon Championships')]
# [('instance', 'http://www.wikidata.org/entity/Q2714801'), ('name', '1935 Australian Championships')]
# [('instance', 'http://www.wikidata.org/entity/Q2718197'), ('name', '1937 Australian Championships')]
# [('instance', 'http://www.wikidata.org/entity/Q677149'), ('name', '1936 Australian Championships')]
# [('instance', 'http://www.wikidata.org/entity/Q686155'), ('name', '1988 US Open')]
# [('instance', 'http://www.wikidata.org/entity/Q2440726'), ('name', '1960 French Championships')]
# [('instance', 'http://www.wikidata.org/entity/Q948754'), ('name', '1959 French Championships')]
# [('instance', 'http://www.wikidata.org/entity/Q2951371'), ('name', '1895 French Championships')]
# [('instance', 'http://www.wikidata.org/entity/Q2951373'), ('name', '1896 French Championships')]
# [('instance', 'http://www.wikidata.org/entity/Q2951375'), ('name', '1897 French Championships')]
# [('instance', 'http://www.wikidata.org/entity/Q2951388'), ('name', '1909 French Championships')]
# [('instance', 'http://www.wikidata.org/entity/Q2951389'), ('name', '1910 French Championships')]
# [('instance', 'http://www.wikidata.org/entity/Q726659'), ('name', '1911 French Championships')]
# [('instance', 'http://www.wikidata.org/entity/Q2540093'), ('name', '1930 French Championships')]
# [('instance', 'http://www.wikidata.org/entity/Q17482052'), ('name', '2015 Australian Open')]
# [('instance', 'http://www.wikidata.org/entity/Q18410121'), ('name', '2015 Wimbledon Championships')]
# [('instance', 'http://www.wikidata.org/entity/Q2410146'), ('name', '1932 U.S. National Championships')]
# [('instance', 'http://www.wikidata.org/entity/Q2411531'), ('name', '1916 U.S. National Championships')]
# [('instance', 'http://www.wikidata.org/entity/Q2121893'), ('name', '1903 Wimbledon Championships')]
# [('instance', 'http://www.wikidata.org/entity/Q2714794'), ('name', '1928 Australian Championships')]
# [('instance', 'http://www.wikidata.org/entity/Q367739'), ('name', '1994 Australian Open')]
# [('instance', 'http://www.wikidata.org/entity/Q420849'), ('name', '1977 Australian Open')]
# [('instance', 'http://www.wikidata.org/entity/Q476638'), ('name', '2010 Wimbledon Championships')]
# [('instance', 'http://www.wikidata.org/entity/Q518011'), ('name', '2004 Australian Open')]
# 100

# %%
# write your queries
# Consider the country for sport property of the tennis player (NO Country of citizenship). 
# Return the countries with at least one player who won at least one edition of each Grand Slam (the result set must be a list of country IRI and label).

# [('p', 'http://www.wikidata.org/prop/direct/P1532'), ('name', 'country for sport')]

# P31 ('instance of')
# P527 ('has part')
# P1346 ('winner')

#[('obj', 'http://www.wikidata.org/entity/Q43605'), ('objName', 'French Open')]
#[('obj', 'http://www.wikidata.org/entity/Q123577'), ('objName', 'US Open')]
#[('obj', 'http://www.wikidata.org/entity/Q41520'), ('objName', 'Wimbledon Championships')]
#[('obj', 'http://www.wikidata.org/entity/Q60874'), ('objName', 'Australian Open')]

# finding ways to group all four tournament by year

queryString = """

PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
SELECT DISTINCT ?p ?pName
WHERE {
   VALUES (?tournament){
       (wd:Q43605)
       (wd:Q123577)
       (wd:Q41520)
       (wd:Q60874)
   }
   # ?yearlyTournament wdt:P31 ?tournament.
   #?yearlyTournament wdt:P527 ?subTournament.
   # ?yearlyTournament ?p ?o.
   
   # ?yearlyTournament sc:name ?yearlyTournamentName.
   # ?p sc:name ?pName.
   
}
LIMIT 20

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1132'), ('pName', 'number of participants')]
# [('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity')]
# [('p', 'http://www.wikidata.org/prop/direct/P155'), ('pName', 'follows')]
# [('p', 'http://www.wikidata.org/prop/direct/P156'), ('pName', 'followed by')]
# [('p', 'http://www.wikidata.org/prop/direct/P17'), ('pName', 'country')]
# [('p', 'http://www.wikidata.org/prop/direct/P18'), ('pName', 'image')]
# [('p', 'http://www.wikidata.org/prop/direct/P2094'), ('pName', 'competition class')]
# [('p', 'http://www.wikidata.org/prop/direct/P214'), ('pName', 'VIAF ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P227'), ('pName', 'GND ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2581'), ('pName', 'BabelNet ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2671'), ('pName', 'Google Knowledge Graph ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P276'), ('pName', 'location')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('p', 'http://www.wikidata.org/prop/direct/P3417'), ('pName', 'Quora topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P361'), ('pName', 'part of')]
# [('p', 'http://www.wikidata.org/prop/direct/P373'), ('pName', 'Commons category')]
# [('p', 'http://www.wikidata.org/prop/direct/P393'), ('pName', 'edition number')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part')]
# [('p', 'http://www.wikidata.org/prop/direct/P580'), ('pName', 'start time')]
# 20

# %%
# write your queries
# Consider the country for sport property of the tennis player (NO Country of citizenship). 
# Return the countries with at least one player who won at least one edition of each Grand Slam (the result set must be a list of country IRI and label).

# [('p', 'http://www.wikidata.org/prop/direct/P1532'), ('name', 'country for sport')]

# P31 ('instance of')
# P527 ('has part')
# P1346 ('winner')

#[('obj', 'http://www.wikidata.org/entity/Q43605'), ('objName', 'French Open')]
#[('obj', 'http://www.wikidata.org/entity/Q123577'), ('objName', 'US Open')]
#[('obj', 'http://www.wikidata.org/entity/Q41520'), ('objName', 'Wimbledon Championships')]
#[('obj', 'http://www.wikidata.org/entity/Q60874'), ('objName', 'Australian Open')]

# finding ways to group all four tournament by year

queryString = """

PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
SELECT DISTINCT ?p ?pName ?o
WHERE {
   VALUES (?tournament){
       (wd:Q43605)
       (wd:Q123577)
       (wd:Q41520)
       (wd:Q60874)
   }
   VALUES (?p){
       (wdt:P6880)
       #(wdt:P393)
       (wd:P361)
       (wd:P31)
   }
   # ?yearlyTournament wdt:P31 ?tournament.
   #?yearlyTournament wdt:P527 ?subTournament.
   # ?yearlyTournament ?p ?o.
   
   # ?yearlyTournament sc:name ?yearlyTournamentName.
   # ?p sc:name ?pName.
   
}
LIMIT 200

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'wimbledon/540/2004/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'australian-open/580/1969/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'us-open/560/2000/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'roland-garros/520/1983/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'roland-garros/520/2000/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'wimbledon/540/1978/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'wimbledon/540/1971/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'french-championships/520/1928/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'wimbledon/540/2014/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'australian-open/580/2016/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'australian-open/580/2017/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'wimbledon/540/2018/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'roland-garros/520/1979/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'australian-championships/580/1959/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'australian-championships/580/1957/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'roland-garros/520/1980/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'australian-championships/580/1958/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'wimbledon/540/1974/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'roland-garros/520/1981/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'roland-garros/520/1969/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'australian-open/580/1975/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'australian-open/580/1972/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'australian-open/580/1974/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'australian-open/580/1976/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'us-open/560/1971/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'roland-garros/520/2008/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'wimbledon/540/1955/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'wimbledon/540/1956/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'wimbledon/540/1957/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'wimbledon/540/1958/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'french-championships/520/1938/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'french-championships/520/1935/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'australian-championships/580/1946/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'australian-championships/580/1962/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'french-championships/520/1952/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'australian-open/580/2006/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'australian-championships/580/1931/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'french-championships/520/1946/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'french-championships/520/1951/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'french-championships/520/1939/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'french-championships/520/1950/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'wimbledon/540/2016/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'us-open/560/2016/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'roland-garros/520/2017/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'wimbledon/540/1988/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'roland-garros/520/2011/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'roland-garros/520/2010/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'roland-garros/520/2009/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'wimbledon/540/2008/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'australian-open/580/2008/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'us-open/560/2007/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'wimbledon/540/1980/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'wimbledon/540/1929/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'wimbledon/540/1930/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'wimbledon/540/1933/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'australian-open/580/1970/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'australian-open/580/2009/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'australian-open/580/2010/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'wimbledon/540/1968/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'roland-garros/520/1988/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'wimbledon/540/1954/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'wimbledon/540/2009/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'australian-championships/580/1935/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'australian-championships/580/1937/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'australian-championships/580/1936/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'us-open/560/1988/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'french-championships/520/1960/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'french-championships/520/1959/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'french-championships/520/1930/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'australian-open/580/2015/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'wimbledon/540/2015/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'australian-championships/580/1928/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'australian-open/580/1994/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'wimbledon/540/2010/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'australian-open/580/2004/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'roland-garros/520/1992/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'australian-open/580/2005/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'australian-championships/580/1930/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'australian-championships/580/1929/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'australian-open/580/1989/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'australian-open/580/2000/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'australian-open/580/2013/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'us-open/560/1999/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'wimbledon/540/1976/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'wimbledon/540/1969/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'wimbledon/540/1970/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'us-open/560/2006/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'wimbledon/540/1946/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'roland-garros/520/1971/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'french-championships/520/1929/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'roland-garros/520/2003/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'wimbledon/540/1981/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'us-open/560/1974/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'french-championships/520/1967/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'french-championships/520/1953/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'french-championships/520/1949/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'wimbledon/540/1985/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'wimbledon/540/1935/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'french-championships/520/1927/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'wimbledon/540/1975/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'wimbledon/540/1984/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'french-championships/520/1963/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'us-open/560/1998/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'us-open/560/1983/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'us-open/560/1990/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'us-open/560/1993/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'us-open/560/2017/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'roland-garros/520/1999/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'us-open/560/1980/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'wimbledon/540/2011/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'wimbledon/540/2012/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'wimbledon/540/1992/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'wimbledon/540/2013/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'us-open/560/1994/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'us-open/560/2011/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'australian-open/580/1980/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'us-open/560/1989/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'australian-open/580/1981/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'australian-open/580/1979/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'wimbledon/540/1977/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'wimbledon/540/2001/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'us-open/560/1995/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'wimbledon/540/2006/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'us-open/560/1968/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'roland-garros/520/1978/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'wimbledon/540/1973/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'us-open/560/1970/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'roland-garros/520/2002/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'wimbledon/540/1991/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'roland-garros/520/2005/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'roland-garros/520/1998/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'roland-garros/520/1997/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'wimbledon/540/1994/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'roland-garros/520/1986/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'wimbledon/540/1972/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'wimbledon/540/1939/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'wimbledon/540/1990/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'wimbledon/540/1950/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'french-championships/520/1925/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'french-championships/520/1926/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'australian-open/580/1987/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'french-championships/520/1955/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'french-championships/520/1961/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'french-championships/520/1956/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'french-championships/520/1954/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'australian-championships/580/1940/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'australian-championships/580/1947/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'australian-championships/580/1955/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'wimbledon/540/1993/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'us-open/560/2009/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'french-championships/520/1965/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'australian-championships/580/1956/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'australian-championships/580/1965/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'australian-championships/580/1963/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'australian-championships/580/1964/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'australian-open/580/1993/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'australian-open/580/1973/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'australian-open/580/1999/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'australian-open/580/2007/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'australasian-championships/580/1919/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'roland-garros/520/2014/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'australian-open/580/2002/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'us-open/560/1985/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'wimbledon/540/2007/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'wimbledon/540/1961/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'wimbledon/540/1962/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'wimbledon/540/1963/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'roland-garros/520/2001/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'roland-garros/520/1970/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'roland-garros/520/1985/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'roland-garros/520/1995/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'roland-garros/520/1989/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'french-championships/520/1962/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'australian-championships/580/1932/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'australian-championships/580/1933/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'australian-championships/580/1939/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'australian-championships/580/1950/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'australian-championships/580/1938/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'roland-garros/520/1994/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'australian-championships/580/1952/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'roland-garros/520/2012/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'wimbledon/540/1999/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'wimbledon/540/1979/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'roland-garros/520/2006/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'roland-garros/520/2004/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'us-open/560/1969/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'french-championships/520/1932/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'french-championships/520/1934/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'us-open/560/2012/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'french-championships/520/1933/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'roland-garros/520/1974/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'roland-garros/520/1973/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'roland-garros/520/1975/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'wimbledon/540/1960/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'roland-garros/520/1982/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'wimbledon/540/1952/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'us-open/560/1991/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'us-open/560/1986/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'us-open/560/1981/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'wimbledon/540/1966/results')]
# 200

# %%
# write your queries
# Consider the country for sport property of the tennis player (NO Country of citizenship). 
# Return the countries with at least one player who won at least one edition of each Grand Slam (the result set must be a list of country IRI and label).

# [('p', 'http://www.wikidata.org/prop/direct/P1532'), ('name', 'country for sport')]

# P31 ('instance of')
# P527 ('has part')
# P1346 ('winner')

#[('obj', 'http://www.wikidata.org/entity/Q43605'), ('objName', 'French Open')]
#[('obj', 'http://www.wikidata.org/entity/Q123577'), ('objName', 'US Open')]
#[('obj', 'http://www.wikidata.org/entity/Q41520'), ('objName', 'Wimbledon Championships')]
#[('obj', 'http://www.wikidata.org/entity/Q60874'), ('objName', 'Australian Open')]

# finding ways to group all four tournament by year

queryString = """

PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
SELECT DISTINCT ?p ?pName ?o
WHERE {
   VALUES (?tournament){
       (wd:Q43605)
       (wd:Q123577)
       (wd:Q41520)
       (wd:Q60874)
   }
   VALUES (?p){
       (wdt:P6880)
       #(wdt:P393)
       (wdt:P1346)#1346winner
       (wdt:P582)#, ('pName', 'end time')]
   }
   # ?yearlyTournament wdt:P31 ?tournament.
   #?yearlyTournament wdt:P527 ?subTournament.
   # ?yearlyTournament ?p ?o.
   
   # ?yearlyTournament sc:name ?yearlyTournamentName.
   # ?p sc:name ?pName.
   
}
LIMIT 200

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'wimbledon/540/2004/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P582'), ('pName', 'end time'), ('o', '2004-07-04T00:00:00Z')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'australian-open/580/1969/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'us-open/560/2000/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'roland-garros/520/1983/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'roland-garros/520/2000/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'wimbledon/540/1978/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P582'), ('pName', 'end time'), ('o', '1978-07-08T00:00:00Z')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'wimbledon/540/1971/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P582'), ('pName', 'end time'), ('o', '1971-07-03T00:00:00Z')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'french-championships/520/1928/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'wimbledon/540/2014/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P582'), ('pName', 'end time'), ('o', '2014-07-06T00:00:00Z')]
# [('p', 'http://www.wikidata.org/prop/direct/P582'), ('pName', 'end time'), ('o', '2014-09-08T00:00:00Z')]
# [('p', 'http://www.wikidata.org/prop/direct/P582'), ('pName', 'end time'), ('o', '1906-12-31T00:00:00Z')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'australian-open/580/2016/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P582'), ('pName', 'end time'), ('o', '2016-01-31T00:00:00Z')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'australian-open/580/2017/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P582'), ('pName', 'end time'), ('o', '2017-01-29T00:00:00Z')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'wimbledon/540/2018/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'roland-garros/520/1979/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'australian-championships/580/1959/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P582'), ('pName', 'end time'), ('o', '1959-01-26T00:00:00Z')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'australian-championships/580/1957/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P582'), ('pName', 'end time'), ('o', '1957-01-28T00:00:00Z')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'roland-garros/520/1980/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'australian-championships/580/1958/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P582'), ('pName', 'end time'), ('o', '1958-01-27T00:00:00Z')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'wimbledon/540/1974/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P582'), ('pName', 'end time'), ('o', '1974-07-06T00:00:00Z')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'roland-garros/520/1981/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'roland-garros/520/1969/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'australian-open/580/1975/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'australian-open/580/1972/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'australian-open/580/1974/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'australian-open/580/1976/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'us-open/560/1971/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'roland-garros/520/2008/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'wimbledon/540/1955/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P582'), ('pName', 'end time'), ('o', '1955-07-02T00:00:00Z')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'wimbledon/540/1956/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P582'), ('pName', 'end time'), ('o', '1956-07-07T00:00:00Z')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'wimbledon/540/1957/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P582'), ('pName', 'end time'), ('o', '1957-07-06T00:00:00Z')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'wimbledon/540/1958/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P582'), ('pName', 'end time'), ('o', '1958-07-05T00:00:00Z')]
# [('p', 'http://www.wikidata.org/prop/direct/P582'), ('pName', 'end time'), ('o', '1968-01-29T00:00:00Z')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'french-championships/520/1938/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'french-championships/520/1935/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'australian-championships/580/1946/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P582'), ('pName', 'end time'), ('o', '1946-01-29T00:00:00Z')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'australian-championships/580/1962/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P582'), ('pName', 'end time'), ('o', '1962-01-15T00:00:00Z')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'french-championships/520/1952/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P582'), ('pName', 'end time'), ('o', '1952-06-02T00:00:00Z')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'australian-open/580/2006/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P582'), ('pName', 'end time'), ('o', '2006-01-29T00:00:00Z')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'australian-championships/580/1931/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P582'), ('pName', 'end time'), ('o', '1881-07-13T00:00:00Z')]
# [('p', 'http://www.wikidata.org/prop/direct/P582'), ('pName', 'end time'), ('o', '1882-07-17T00:00:00Z')]
# [('p', 'http://www.wikidata.org/prop/direct/P582'), ('pName', 'end time'), ('o', '1883-07-16T00:00:00Z')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'french-championships/520/1946/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P582'), ('pName', 'end time'), ('o', '1946-07-28T00:00:00Z')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'french-championships/520/1951/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P582'), ('pName', 'end time'), ('o', '1951-06-03T00:00:00Z')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'french-championships/520/1939/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'french-championships/520/1950/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P582'), ('pName', 'end time'), ('o', '1950-06-04T00:00:00Z')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'wimbledon/540/2016/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P582'), ('pName', 'end time'), ('o', '2016-07-10T00:00:00Z')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'us-open/560/2016/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P582'), ('pName', 'end time'), ('o', '2016-09-11T00:00:00Z')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'roland-garros/520/2017/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P582'), ('pName', 'end time'), ('o', '2017-06-11T00:00:00Z')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'wimbledon/540/1988/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P582'), ('pName', 'end time'), ('o', '1988-07-04T00:00:00Z')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'roland-garros/520/2011/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'roland-garros/520/2010/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'roland-garros/520/2009/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'wimbledon/540/2008/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P582'), ('pName', 'end time'), ('o', '2008-07-06T00:00:00Z')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'australian-open/580/2008/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P582'), ('pName', 'end time'), ('o', '2008-01-27T00:00:00Z')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'us-open/560/2007/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'wimbledon/540/1980/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P582'), ('pName', 'end time'), ('o', '1980-07-05T00:00:00Z')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'wimbledon/540/1929/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P582'), ('pName', 'end time'), ('o', '1929-07-06T00:00:00Z')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'wimbledon/540/1930/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P582'), ('pName', 'end time'), ('o', '1930-07-07T00:00:00Z')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'wimbledon/540/1933/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P582'), ('pName', 'end time'), ('o', '1933-07-08T00:00:00Z')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'australian-open/580/1970/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'australian-open/580/2009/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P582'), ('pName', 'end time'), ('o', '2009-02-01T00:00:00Z')]
# [('p', 'http://www.wikidata.org/prop/direct/P582'), ('pName', 'end time'), ('o', '2011-01-30T00:00:00Z')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'australian-open/580/2010/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P582'), ('pName', 'end time'), ('o', '2010-01-31T00:00:00Z')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'wimbledon/540/1968/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P582'), ('pName', 'end time'), ('o', '1968-07-06T00:00:00Z')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'roland-garros/520/1988/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'wimbledon/540/1954/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P582'), ('pName', 'end time'), ('o', '1954-07-03T00:00:00Z')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'wimbledon/540/2009/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P582'), ('pName', 'end time'), ('o', '2009-07-05T00:00:00Z')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'australian-championships/580/1935/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'australian-championships/580/1937/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'australian-championships/580/1936/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'us-open/560/1988/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'french-championships/520/1960/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'french-championships/520/1959/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P582'), ('pName', 'end time'), ('o', '1959-05-31T00:00:00Z')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'french-championships/520/1930/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'australian-open/580/2015/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P582'), ('pName', 'end time'), ('o', '2015-02-01T00:00:00Z')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'wimbledon/540/2015/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P582'), ('pName', 'end time'), ('o', '2015-07-12T00:00:00Z')]
# [('p', 'http://www.wikidata.org/prop/direct/P582'), ('pName', 'end time'), ('o', '1903-07-01T00:00:00Z')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'australian-championships/580/1928/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'australian-open/580/1994/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P582'), ('pName', 'end time'), ('o', '1994-01-30T00:00:00Z')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'wimbledon/540/2010/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P582'), ('pName', 'end time'), ('o', '2010-07-04T00:00:00Z')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'australian-open/580/2004/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P582'), ('pName', 'end time'), ('o', '2004-02-01T00:00:00Z')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'roland-garros/520/1992/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'australian-open/580/2005/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P582'), ('pName', 'end time'), ('o', '2005-01-30T00:00:00Z')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'australian-championships/580/1930/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'australian-championships/580/1929/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'australian-open/580/1989/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'australian-open/580/2000/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P582'), ('pName', 'end time'), ('o', '2000-01-30T00:00:00Z')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'australian-open/580/2013/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P582'), ('pName', 'end time'), ('o', '2013-01-27T00:00:00Z')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'us-open/560/1999/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'wimbledon/540/1976/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P582'), ('pName', 'end time'), ('o', '1976-07-03T00:00:00Z')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'wimbledon/540/1969/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P582'), ('pName', 'end time'), ('o', '1969-07-05T00:00:00Z')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'wimbledon/540/1970/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P582'), ('pName', 'end time'), ('o', '1970-07-04T00:00:00Z')]
# [('p', 'http://www.wikidata.org/prop/direct/P582'), ('pName', 'end time'), ('o', '1899-06-27T00:00:00Z')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'us-open/560/2006/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P582'), ('pName', 'end time'), ('o', '1911-07-08T00:00:00Z')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'wimbledon/540/1946/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P582'), ('pName', 'end time'), ('o', '1946-07-06T00:00:00Z')]
# [('p', 'http://www.wikidata.org/prop/direct/P582'), ('pName', 'end time'), ('o', '1910-07-02T00:00:00Z')]
# [('p', 'http://www.wikidata.org/prop/direct/P582'), ('pName', 'end time'), ('o', '1898-06-28T00:00:00Z')]
# [('p', 'http://www.wikidata.org/prop/direct/P582'), ('pName', 'end time'), ('o', '1908-07-01T00:00:00Z')]
# [('p', 'http://www.wikidata.org/prop/direct/P582'), ('pName', 'end time'), ('o', '1901-07-03T00:00:00Z')]
# [('p', 'http://www.wikidata.org/prop/direct/P582'), ('pName', 'end time'), ('o', '1909-07-05T00:00:00Z')]
# [('p', 'http://www.wikidata.org/prop/direct/P582'), ('pName', 'end time'), ('o', '1900-07-04T00:00:00Z')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'roland-garros/520/1971/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'french-championships/520/1929/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'roland-garros/520/2003/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'wimbledon/540/1981/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P582'), ('pName', 'end time'), ('o', '1981-07-04T00:00:00Z')]
# [('p', 'http://www.wikidata.org/prop/direct/P582'), ('pName', 'end time'), ('o', '1905-07-08T00:00:00Z')]
# [('p', 'http://www.wikidata.org/prop/direct/P582'), ('pName', 'end time'), ('o', '1897-07-01T00:00:00Z')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'us-open/560/1974/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P582'), ('pName', 'end time'), ('o', '1890-07-23T00:00:00Z')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'french-championships/520/1967/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'french-championships/520/1953/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P582'), ('pName', 'end time'), ('o', '1953-05-31T00:00:00Z')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'french-championships/520/1949/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P582'), ('pName', 'end time'), ('o', '1949-05-29T00:00:00Z')]
# [('p', 'http://www.wikidata.org/prop/direct/P582'), ('pName', 'end time'), ('o', '1927-07-04T00:00:00Z')]
# [('p', 'http://www.wikidata.org/prop/direct/P582'), ('pName', 'end time'), ('o', '1928-07-07T00:00:00Z')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'wimbledon/540/1985/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P582'), ('pName', 'end time'), ('o', '1985-07-07T00:00:00Z')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'wimbledon/540/1935/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P582'), ('pName', 'end time'), ('o', '1935-07-06T00:00:00Z')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'french-championships/520/1927/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'wimbledon/540/1975/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P582'), ('pName', 'end time'), ('o', '1975-07-05T00:00:00Z')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'wimbledon/540/1984/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P582'), ('pName', 'end time'), ('o', '1984-07-08T00:00:00Z')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'french-championships/520/1963/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'us-open/560/1998/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'us-open/560/1983/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'us-open/560/1990/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'us-open/560/1993/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'us-open/560/2017/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P582'), ('pName', 'end time'), ('o', '2017-09-10T00:00:00Z')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'roland-garros/520/1999/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'us-open/560/1980/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P582'), ('pName', 'end time'), ('o', '1980-09-07T00:00:00Z')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'wimbledon/540/2011/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P582'), ('pName', 'end time'), ('o', '2011-07-03T00:00:00Z')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'wimbledon/540/2012/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P582'), ('pName', 'end time'), ('o', '2012-07-08T00:00:00Z')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'wimbledon/540/1992/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P582'), ('pName', 'end time'), ('o', '1992-07-05T00:00:00Z')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'wimbledon/540/2013/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P582'), ('pName', 'end time'), ('o', '2013-07-07T00:00:00Z')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'us-open/560/1994/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'us-open/560/2011/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'australian-open/580/1980/results')]
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID'), ('o', 'us-open/560/1989/results')]
# 200

# %%
# write your queries
# Consider the country for sport property of the tennis player (NO Country of citizenship). 
# Return the countries with at least one player who won at least one edition of each Grand Slam (the result set must be a list of country IRI and label).

# [('p', 'http://www.wikidata.org/prop/direct/P1532'), ('name', 'country for sport')]

# P31 ('instance of')
# P527 ('has part')
# P1346 ('winner')

#[('obj', 'http://www.wikidata.org/entity/Q43605'), ('objName', 'French Open')]
#[('obj', 'http://www.wikidata.org/entity/Q123577'), ('objName', 'US Open')]
#[('obj', 'http://www.wikidata.org/entity/Q41520'), ('objName', 'Wimbledon Championships')]
#[('obj', 'http://www.wikidata.org/entity/Q60874'), ('objName', 'Australian Open')]

# finding ways to group all four tournament by year

queryString = """

PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
SELECT DISTINCT ?p ?pName ?o
WHERE {
   VALUES (?tournament){
       (wd:Q43605)
       (wd:Q123577)
       (wd:Q41520)
       (wd:Q60874)
   }
   VALUES (?p){
       #(wdt:P6880)
       #(wdt:P393)
       (wdt:P1346)#1346winner
       #(wdt:P582)#, ('pName', 'end time')]
   }
   # ?yearlyTournament wdt:P31 ?tournament.
   #?yearlyTournament wdt:P527 ?subTournament.
   # ?yearlyTournament ?p ?o.
   
   # ?yearlyTournament sc:name ?yearlyTournamentName.
   # ?p sc:name ?pName.
   
}
LIMIT 200

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# Empty

# %%
# write your queries
# Consider the country for sport property of the tennis player (NO Country of citizenship). 
# Return the countries with at least one player who won at least one edition of each Grand Slam (the result set must be a list of country IRI and label).

# [('p', 'http://www.wikidata.org/prop/direct/P1532'), ('name', 'country for sport')]

# P31 ('instance of')
# P527 ('has part')
# P1346 ('winner')

#[('obj', 'http://www.wikidata.org/entity/Q43605'), ('objName', 'French Open')]
#[('obj', 'http://www.wikidata.org/entity/Q123577'), ('objName', 'US Open')]
#[('obj', 'http://www.wikidata.org/entity/Q41520'), ('objName', 'Wimbledon Championships')]
#[('obj', 'http://www.wikidata.org/entity/Q60874'), ('objName', 'Australian Open')]

# finding ways to group all four tournament by year

queryString = """

PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
SELECT DISTINCT ?p ?pName
WHERE {
   VALUES (?tournament){
       (wd:Q43605)
       (wd:Q123577)
       (wd:Q41520)
       (wd:Q60874)
   }
   # ?yearlyTournament wdt:P31 ?tournament.
   # ?yearlyTournament wdt:P527 ?subTournament.
   # ?subTournament ?p ?o.
   
   # ?p sc:name ?pName.
   
}
LIMIT 200

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P1132'), ('pName', 'number of participants')]
# [('p', 'http://www.wikidata.org/prop/direct/P1269'), ('pName', 'facet of')]
# [('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner')]
# [('p', 'http://www.wikidata.org/prop/direct/P155'), ('pName', 'follows')]
# [('p', 'http://www.wikidata.org/prop/direct/P156'), ('pName', 'followed by')]
# [('p', 'http://www.wikidata.org/prop/direct/P17'), ('pName', 'country')]
# [('p', 'http://www.wikidata.org/prop/direct/P18'), ('pName', 'image')]
# [('p', 'http://www.wikidata.org/prop/direct/P2094'), ('pName', 'competition class')]
# [('p', 'http://www.wikidata.org/prop/direct/P2581'), ('pName', 'BabelNet ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2671'), ('pName', 'Google Knowledge Graph ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('p', 'http://www.wikidata.org/prop/direct/P361'), ('pName', 'part of')]
# [('p', 'http://www.wikidata.org/prop/direct/P393'), ('pName', 'edition number')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part')]
# [('p', 'http://www.wikidata.org/prop/direct/P585'), ('pName', 'point in time')]
# [('p', 'http://www.wikidata.org/prop/direct/P641'), ('pName', 'sport')]
# [('p', 'http://www.wikidata.org/prop/direct/P646'), ('pName', 'Freebase ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P710'), ('pName', 'participant')]
# [('p', 'http://www.wikidata.org/prop/direct/P276'), ('pName', 'location')]
# [('p', 'http://www.wikidata.org/prop/direct/P580'), ('pName', 'start time')]
# [('p', 'http://www.wikidata.org/prop/direct/P582'), ('pName', 'end time')]
# [('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity')]
# [('p', 'http://www.wikidata.org/prop/direct/P3967'), ('pName', 'final event')]
# [('p', 'http://www.wikidata.org/prop/direct/P373'), ('pName', 'Commons category')]
# [('p', 'http://www.wikidata.org/prop/direct/P3085'), ('pName', 'qualifies for event')]
# [('p', 'http://www.wikidata.org/prop/direct/P1552'), ('pName', 'has quality')]
# [('p', 'http://www.wikidata.org/prop/direct/P2670'), ('pName', 'has parts of the class')]
# 27

# %%
# write your queries
# Consider the country for sport property of the tennis player (NO Country of citizenship). 
# Return the countries with at least one player who won at least one edition of each Grand Slam (the result set must be a list of country IRI and label).

# [('p', 'http://www.wikidata.org/prop/direct/P1532'), ('name', 'country for sport')]

# P31 ('instance of')
# P527 ('has part')
# P1346 ('winner')

#[('obj', 'http://www.wikidata.org/entity/Q43605'), ('objName', 'French Open')]
#[('obj', 'http://www.wikidata.org/entity/Q123577'), ('objName', 'US Open')]
#[('obj', 'http://www.wikidata.org/entity/Q41520'), ('objName', 'Wimbledon Championships')]
#[('obj', 'http://www.wikidata.org/entity/Q60874'), ('objName', 'Australian Open')]

# finding ways to group all four tournament by year

queryString = """

PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
SELECT DISTINCT ?subTournament ?p ?pName ?o ?oName
WHERE {
   VALUES (?tournament){
       (wd:Q43605)
       (wd:Q123577)
       (wd:Q41520)
       (wd:Q60874)
   }
   # ?yearlyTournament wdt:P31 ?tournament.
   # ?yearlyTournament wdt:P527 ?subTournament.
   # ?subTournament wdt:P1346 ?o.
   
   # ?p sc:name ?pName.
   # ?o sc:name ?oName.
   FILTER (?p = wdt:P1346 )
}
LIMIT 20

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('subTournament', 'http://www.wikidata.org/entity/Q16024356'), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner'), ('o', 'http://www.wikidata.org/entity/Q299959'), ('oName', 'Eileen Bennett Whittingstall')]
# [('subTournament', 'http://www.wikidata.org/entity/Q18888358'), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner'), ('o', 'http://www.wikidata.org/entity/Q18918709'), ('oName', 'Markéta Vondroušová')]
# [('subTournament', 'http://www.wikidata.org/entity/Q26155846'), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner'), ('o', 'http://www.wikidata.org/entity/Q193661'), ('oName', 'Stan Wawrinka')]
# [('subTournament', 'http://www.wikidata.org/entity/Q4630192'), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner'), ('o', 'http://www.wikidata.org/entity/Q193661'), ('oName', 'Stan Wawrinka')]
# [('subTournament', 'http://www.wikidata.org/entity/Q19868596'), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner'), ('o', 'http://www.wikidata.org/entity/Q193661'), ('oName', 'Stan Wawrinka')]
# [('subTournament', 'http://www.wikidata.org/entity/Q963544'), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner'), ('o', 'http://www.wikidata.org/entity/Q54546'), ('oName', 'Nancy Richey')]
# [('subTournament', 'http://www.wikidata.org/entity/Q2406262'), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner'), ('o', 'http://www.wikidata.org/entity/Q54546'), ('oName', 'Nancy Richey')]
# [('subTournament', 'http://www.wikidata.org/entity/Q3037585'), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner'), ('o', 'http://www.wikidata.org/entity/Q54546'), ('oName', 'Nancy Richey')]
# [('subTournament', 'http://www.wikidata.org/entity/Q14744870'), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner'), ('o', 'http://www.wikidata.org/entity/Q14905846'), ('oName', 'Borna Ćorić')]
# [('subTournament', 'http://www.wikidata.org/entity/Q4339782'), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner'), ('o', 'http://www.wikidata.org/entity/Q207352'), ('oName', 'Agnieszka Radwańska')]
# [('subTournament', 'http://www.wikidata.org/entity/Q22231236'), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner'), ('o', 'http://www.wikidata.org/entity/Q22958938'), ('oName', 'Alex de Minaur')]
# [('subTournament', 'http://www.wikidata.org/entity/Q22231236'), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner'), ('o', 'http://www.wikidata.org/entity/Q22959065'), ('oName', 'Blake Ellis')]
# [('subTournament', 'http://www.wikidata.org/entity/Q2406367'), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner'), ('o', 'http://www.wikidata.org/entity/Q239758'), ('oName', 'Arantxa Rus')]
# [('subTournament', 'http://www.wikidata.org/entity/Q1752656'), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner'), ('o', 'http://www.wikidata.org/entity/Q435255'), ('oName', 'Shirley Brasher')]
# [('subTournament', 'http://www.wikidata.org/entity/Q25476670'), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner'), ('o', 'http://www.wikidata.org/entity/Q439942'), ('oName', 'Marcelo Melo')]
# [('subTournament', 'http://www.wikidata.org/entity/Q18702367'), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner'), ('o', 'http://www.wikidata.org/entity/Q439942'), ('oName', 'Marcelo Melo')]
# [('subTournament', 'http://www.wikidata.org/entity/Q662297'), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner'), ('o', 'http://www.wikidata.org/entity/Q445602'), ('oName', 'Manuel Santana')]
# [('subTournament', 'http://www.wikidata.org/entity/Q1752228'), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner'), ('o', 'http://www.wikidata.org/entity/Q445602'), ('oName', 'Manuel Santana')]
# [('subTournament', 'http://www.wikidata.org/entity/Q2179727'), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner'), ('o', 'http://www.wikidata.org/entity/Q455136'), ('oName', 'Anders Järryd')]
# [('subTournament', 'http://www.wikidata.org/entity/Q3883705'), ('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner'), ('o', 'http://www.wikidata.org/entity/Q455136'), ('oName', 'Anders Järryd')]
# 20

# %%
# write your queries
# Consider the country for sport property of the tennis player (NO Country of citizenship). 
# Return the countries with at least one player who won at least one edition of each Grand Slam (the result set must be a list of country IRI and label).

# tennis player (wd:Q10833314)
# Q589310 = "tennis at the 2000 Summer Olympics – men's singles"
# P641 = 'sport'
# Q46190676 = tennis event

queryString = """

SELECT DISTINCT ?p ?pName ?obj ?objName 
WHERE {
   # bind something
   wd:Q46190676 ?p ?obj .
   # get the label
   # ?p sc:name ?pName .
   # ?obj sc:name ?objName.
}
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P2670'), ('pName', 'has parts of the class'), ('obj', 'http://www.wikidata.org/entity/Q21170330'), ('objName', 'tennis qualification event')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('obj', 'http://www.wikidata.org/entity/P361'), ('objName', 'part of')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('obj', 'http://www.wikidata.org/entity/Q16510064'), ('objName', 'sporting event')]
# [('p', 'http://www.wikidata.org/prop/direct/P641'), ('pName', 'sport'), ('obj', 'http://www.wikidata.org/entity/Q847'), ('objName', 'tennis')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('obj', 'http://www.wikidata.org/entity/P641'), ('objName', 'sport')]
# [('p', 'http://www.wikidata.org/prop/direct/P361'), ('pName', 'part of'), ('obj', 'http://www.wikidata.org/entity/Q47345468'), ('objName', 'tennis tournament edition')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('obj', 'http://www.wikidata.org/entity/P1346'), ('objName', 'winner')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('obj', 'http://www.wikidata.org/entity/P710'), ('objName', 'participant')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('obj', 'http://www.wikidata.org/entity/P2094'), ('objName', 'competition class')]
# [('p', 'http://www.wikidata.org/prop/direct/P2670'), ('pName', 'has parts of the class'), ('obj', 'http://www.wikidata.org/entity/Q47459169'), ('objName', 'tennis match')]
# [('p', 'http://www.wikidata.org/prop/direct/P1552'), ('pName', 'has quality'), ('obj', 'http://www.wikidata.org/entity/Q1967745'), ('objName', 'type of tennis match')]
# 11

# %%
# write your queries
# Consider the country for sport property of the tennis player (NO Country of citizenship). 
# Return the countries with at least one player who won at least one edition of each Grand Slam (the result set must be a list of country IRI and label).

# tennis player (wd:Q10833314)
# Q589310 = "tennis at the 2000 Summer Olympics – men's singles"
# P641 = 'sport'
# Q46190676 = tennis event

queryString = """

SELECT DISTINCT ?p ?pName ?obj ?objName 
WHERE {
   # bind something
   wd:Q47345468 ?p ?obj .
   # get the label
   # ?p sc:name ?pName .
   # ?obj sc:name ?objName.
}
LIMIT 20
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('obj', 'http://www.wikidata.org/entity/P393'), ('objName', 'edition number')]
# [('p', 'http://www.wikidata.org/prop/direct/P2670'), ('pName', 'has parts of the class'), ('obj', 'http://www.wikidata.org/entity/Q47382471'), ('objName', 'day-by-day summary')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('obj', 'http://www.wikidata.org/entity/P580'), ('objName', 'start time')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('obj', 'http://www.wikidata.org/entity/P582'), ('objName', 'end time')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('obj', 'http://www.wikidata.org/entity/P17'), ('objName', 'country')]
# [('p', 'http://www.wikidata.org/prop/direct/P361'), ('pName', 'part of'), ('obj', 'http://www.wikidata.org/entity/Q13219666'), ('objName', 'tennis tournament')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('obj', 'http://www.wikidata.org/entity/Q27020041'), ('objName', 'sports season')]
# [('p', 'http://www.wikidata.org/prop/direct/P641'), ('pName', 'sport'), ('obj', 'http://www.wikidata.org/entity/Q847'), ('objName', 'tennis')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('obj', 'http://www.wikidata.org/entity/P527'), ('objName', 'has part')]
# [('p', 'http://www.wikidata.org/prop/direct/P361'), ('pName', 'part of'), ('obj', 'http://www.wikidata.org/entity/Q47358534'), ('objName', 'tennis tour edition')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('obj', 'http://www.wikidata.org/entity/P641'), ('objName', 'sport')]
# [('p', 'http://www.wikidata.org/prop/direct/P2670'), ('pName', 'has parts of the class'), ('obj', 'http://www.wikidata.org/entity/Q46190676'), ('objName', 'tennis event')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('obj', 'http://www.wikidata.org/entity/P276'), ('objName', 'location')]
# [('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('obj', 'http://www.wikidata.org/entity/P585'), ('objName', 'point in time')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('obj', 'http://www.wikidata.org/entity/Q27968055'), ('objName', 'recurrent event edition')]
# 15

# %% [markdown]
# #### Cannot find any property (over yearly edition of Grand Slam which holds the winner of that edition)

# %% [markdown]
# #### Possible Solution (SOL 1)
#
# ```
# as we know each Grand Slam should have exaclty 4 tournaments each year,
# a solution could be:
# ```
# ```
# group by (yearly grand slam, winner) -> if there is a winner with exaclty 4 tournament won -> find his country -> return sol
# ```

# %%
# write your queries
# Consider the country for sport property of the tennis player (NO Country of citizenship). 
# Return the countries with at least one player who won at least one edition of each Grand Slam (the result set must be a list of country IRI and label).

# [('p', 'http://www.wikidata.org/prop/direct/P1532'), ('name', 'country for sport')]

# P31 ('instance of')
# P527 ('has part')
# P1346 ('winner')

#[('obj', 'http://www.wikidata.org/entity/Q43605'), ('objName', 'French Open')]
#[('obj', 'http://www.wikidata.org/entity/Q123577'), ('objName', 'US Open')]
#[('obj', 'http://www.wikidata.org/entity/Q41520'), ('objName', 'Wimbledon Championships')]
#[('obj', 'http://www.wikidata.org/entity/Q60874'), ('objName', 'Australian Open')]

# 1) group by tournament and winner of the tournament

queryString = """

PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
SELECT ?tournament ?winner ?winnerName (COUNT(*) as ?tot)
WHERE {
   VALUES (?tournament){
       (wd:Q43605)
       (wd:Q123577)
       (wd:Q41520)
       (wd:Q60874)
   }   
   # ?yearlyTournament wdt:P31 ?tournament.
   # ?yearlyTournament wdt:P527 ?subTournament.
   # ?subTournament wdt:P1346 ?winner.
   
   # get the label 
   # ?yearlyTournament sc:name ?yearlyTournamentName .
   # ?subTournament sc:name ?subTournamentName.
   # ?winner sc:name ?winnerName.
   # ?winner wdt:P569 ?dob   
}
GROUP BY ?tournament ?winner ?winnerName
LIMIT 20

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('tournament', 'http://www.wikidata.org/entity/Q60874'), ('winner', 'http://www.wikidata.org/entity/Q233234'), ('winnerName', 'Virginia Wade'), ('tot', '1')]
# [('tournament', 'http://www.wikidata.org/entity/Q41520'), ('winner', 'http://www.wikidata.org/entity/Q54544'), ('winnerName', 'Gardnar Mulloy'), ('tot', '1')]
# [('tournament', 'http://www.wikidata.org/entity/Q41520'), ('winner', 'http://www.wikidata.org/entity/Q913948'), ('winnerName', 'Mervyn Rose'), ('tot', '1')]
# [('tournament', 'http://www.wikidata.org/entity/Q41520'), ('winner', 'http://www.wikidata.org/entity/Q229005'), ('winnerName', 'Sara Errani'), ('tot', '1')]
# [('tournament', 'http://www.wikidata.org/entity/Q41520'), ('winner', 'http://www.wikidata.org/entity/Q11459'), ('winnerName', 'Serena Williams'), ('tot', '14')]
# [('tournament', 'http://www.wikidata.org/entity/Q41520'), ('winner', 'http://www.wikidata.org/entity/Q53390'), ('winnerName', 'Maureen Connolly'), ('tot', '3')]
# [('tournament', 'http://www.wikidata.org/entity/Q60874'), ('winner', 'http://www.wikidata.org/entity/Q296282'), ('winnerName', 'Leander Paes'), ('tot', '4')]
# [('tournament', 'http://www.wikidata.org/entity/Q41520'), ('winner', 'http://www.wikidata.org/entity/Q53411'), ('winnerName', 'Margaret Osborne duPont'), ('tot', '1')]
# [('tournament', 'http://www.wikidata.org/entity/Q41520'), ('winner', 'http://www.wikidata.org/entity/Q134720'), ('winnerName', 'Martina Hingis'), ('tot', '6')]
# [('tournament', 'http://www.wikidata.org/entity/Q41520'), ('winner', 'http://www.wikidata.org/entity/Q1426'), ('winnerName', 'Roger Federer'), ('tot', '8')]
# [('tournament', 'http://www.wikidata.org/entity/Q60874'), ('winner', 'http://www.wikidata.org/entity/Q54545'), ('winnerName', 'Martina Navratilova'), ('tot', '11')]
# [('tournament', 'http://www.wikidata.org/entity/Q41520'), ('winner', 'http://www.wikidata.org/entity/Q189542'), ('winnerName', 'Stefan Edberg'), ('tot', '2')]
# [('tournament', 'http://www.wikidata.org/entity/Q41520'), ('winner', 'http://www.wikidata.org/entity/Q335312'), ('winnerName', 'Todd Woodbridge'), ('tot', '7')]
# [('tournament', 'http://www.wikidata.org/entity/Q60874'), ('winner', 'http://www.wikidata.org/entity/Q272271'), ('winnerName', 'Coral Buttsworth'), ('tot', '3')]
# [('tournament', 'http://www.wikidata.org/entity/Q41520'), ('winner', 'http://www.wikidata.org/entity/Q14286'), ('winnerName', 'Chris Evert'), ('tot', '2')]
# [('tournament', 'http://www.wikidata.org/entity/Q60874'), ('winner', 'http://www.wikidata.org/entity/Q53338'), ('winnerName', 'Louise Brough'), ('tot', '2')]
# [('tournament', 'http://www.wikidata.org/entity/Q60874'), ('winner', 'http://www.wikidata.org/entity/Q512302'), ('winnerName', 'Ellis Ferreira'), ('tot', '2')]
# [('tournament', 'http://www.wikidata.org/entity/Q41520'), ('winner', 'http://www.wikidata.org/entity/Q442632'), ('winnerName', 'Angela Buxton'), ('tot', '1')]
# [('tournament', 'http://www.wikidata.org/entity/Q60874'), ('winner', 'http://www.wikidata.org/entity/Q17466583'), ('winnerName', 'Naomi Osaka'), ('tot', '2')]
# [('tournament', 'http://www.wikidata.org/entity/Q60874'), ('winner', 'http://www.wikidata.org/entity/Q233332'), ('winnerName', 'Gigi Fernández'), ('tot', '2')]
# 20

# %%
# write your queries
# Consider the country for sport property of the tennis player (NO Country of citizenship). 
# Return the countries with at least one player who won at least one edition of each Grand Slam (the result set must be a list of country IRI and label).

# [('p', 'http://www.wikidata.org/prop/direct/P1532'), ('name', 'country for sport')]

# P31 ('instance of')
# P527 ('has part')
# P1346 ('winner')

#[('obj', 'http://www.wikidata.org/entity/Q43605'), ('objName', 'French Open')]
#[('obj', 'http://www.wikidata.org/entity/Q123577'), ('objName', 'US Open')]
#[('obj', 'http://www.wikidata.org/entity/Q41520'), ('objName', 'Wimbledon Championships')]
#[('obj', 'http://www.wikidata.org/entity/Q60874'), ('objName', 'Australian Open')]

# 1) group by tournament and winner of the tournament

queryString = """

PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
SELECT ?tournament ?tournamentName ?winner ?winnerName (COUNT(*) as ?tot)
WHERE {
   VALUES (?tournament){
       (wd:Q43605)
       (wd:Q123577)
       (wd:Q41520)
       (wd:Q60874)
   }   
   # ?yearlyTournament wdt:P31 ?tournament.
   # ?yearlyTournament wdt:P527 ?subTournament.
   # ?subTournament wdt:P1346 ?winner.
   
   # get the label 
   # ?tournament sc:name ?tournamentName .
   # ?yearlyTournament sc:name ?yearlyTournamentName .
   # ?subTournament sc:name ?subTournamentName.
   # ?winner sc:name ?winnerName.
   # ?winner wdt:P569 ?dob   
}
GROUP BY ?winner ?winnerName ?tournament ?tournamentName
LIMIT 20

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('tournament', 'http://www.wikidata.org/entity/Q41520'), ('tournamentName', 'Wimbledon Championships'), ('winner', 'http://www.wikidata.org/entity/Q104506'), ('winnerName', 'Björn Borg'), ('tot', '5')]
# [('tournament', 'http://www.wikidata.org/entity/Q41520'), ('tournamentName', 'Wimbledon Championships'), ('winner', 'http://www.wikidata.org/entity/Q310419'), ('winnerName', 'Nenad Zimonjić'), ('tot', '1')]
# [('tournament', 'http://www.wikidata.org/entity/Q60874'), ('tournamentName', 'Australian Open'), ('winner', 'http://www.wikidata.org/entity/Q228989'), ('winnerName', 'Lucie Šafářová'), ('tot', '2')]
# [('tournament', 'http://www.wikidata.org/entity/Q41520'), ('tournamentName', 'Wimbledon Championships'), ('winner', 'http://www.wikidata.org/entity/Q457476'), ('winnerName', 'Alexander Peya'), ('tot', '1')]
# [('tournament', 'http://www.wikidata.org/entity/Q41520'), ('tournamentName', 'Wimbledon Championships'), ('winner', 'http://www.wikidata.org/entity/Q26840238'), ('winnerName', 'Iga Świątek'), ('tot', '1')]
# [('tournament', 'http://www.wikidata.org/entity/Q60874'), ('tournamentName', 'Australian Open'), ('winner', 'http://www.wikidata.org/entity/Q228559'), ('winnerName', 'Evonne Goolagong Cawley'), ('tot', '6')]
# [('tournament', 'http://www.wikidata.org/entity/Q41520'), ('tournamentName', 'Wimbledon Championships'), ('winner', 'http://www.wikidata.org/entity/Q139645'), ('winnerName', 'Ulf Schmidt'), ('tot', '1')]
# [('tournament', 'http://www.wikidata.org/entity/Q60874'), ('tournamentName', 'Australian Open'), ('winner', 'http://www.wikidata.org/entity/Q374047'), ('winnerName', 'Adrian Quist'), ('tot', '10')]
# [('tournament', 'http://www.wikidata.org/entity/Q41520'), ('tournamentName', 'Wimbledon Championships'), ('winner', 'http://www.wikidata.org/entity/Q552349'), ('winnerName', 'Jean-Julien Rojer'), ('tot', '1')]
# [('tournament', 'http://www.wikidata.org/entity/Q60874'), ('tournamentName', 'Australian Open'), ('winner', 'http://www.wikidata.org/entity/Q191766'), ('winnerName', 'Samantha Stosur'), ('tot', '2')]
# [('tournament', 'http://www.wikidata.org/entity/Q60874'), ('tournamentName', 'Australian Open'), ('winner', 'http://www.wikidata.org/entity/Q942937'), ('winnerName', 'Scott Draper'), ('tot', '1')]
# [('tournament', 'http://www.wikidata.org/entity/Q60874'), ('tournamentName', 'Australian Open'), ('winner', 'http://www.wikidata.org/entity/Q369257'), ('winnerName', 'Kevin Ullyett'), ('tot', '2')]
# [('tournament', 'http://www.wikidata.org/entity/Q60874'), ('tournamentName', 'Australian Open'), ('winner', 'http://www.wikidata.org/entity/Q54545'), ('winnerName', 'Martina Navratilova'), ('tot', '11')]
# [('tournament', 'http://www.wikidata.org/entity/Q60874'), ('tournamentName', 'Australian Open'), ('winner', 'http://www.wikidata.org/entity/Q3720084'), ('winnerName', 'Nick Kyrgios'), ('tot', '1')]
# [('tournament', 'http://www.wikidata.org/entity/Q60874'), ('tournamentName', 'Australian Open'), ('winner', 'http://www.wikidata.org/entity/Q1711148'), ('winnerName', 'Judy Chaloner'), ('tot', '1')]
# [('tournament', 'http://www.wikidata.org/entity/Q41520'), ('tournamentName', 'Wimbledon Championships'), ('winner', 'http://www.wikidata.org/entity/Q52430'), ('winnerName', 'Daniela Hantuchová'), ('tot', '1')]
# [('tournament', 'http://www.wikidata.org/entity/Q41520'), ('tournamentName', 'Wimbledon Championships'), ('winner', 'http://www.wikidata.org/entity/Q9446'), ('winnerName', 'Pete Sampras'), ('tot', '7')]
# [('tournament', 'http://www.wikidata.org/entity/Q60874'), ('tournamentName', 'Australian Open'), ('winner', 'http://www.wikidata.org/entity/Q53546'), ('winnerName', 'Zina Garrison'), ('tot', '1')]
# [('tournament', 'http://www.wikidata.org/entity/Q60874'), ('tournamentName', 'Australian Open'), ('winner', 'http://www.wikidata.org/entity/Q162639'), ('winnerName', 'Lew Hoad'), ('tot', '1')]
# [('tournament', 'http://www.wikidata.org/entity/Q60874'), ('tournamentName', 'Australian Open'), ('winner', 'http://www.wikidata.org/entity/Q312545'), ('winnerName', 'Roy Emerson'), ('tot', '6')]
# 20

# %%
# write your queries
# Consider the country for sport property of the tennis player (NO Country of citizenship). 
# Return the countries with at least one player who won at least one edition of each Grand Slam (the result set must be a list of country IRI and label).

# [('p', 'http://www.wikidata.org/prop/direct/P1532'), ('name', 'country for sport')]

# P31 ('instance of')
# P527 ('has part')
# P1346 ('winner')

#[('obj', 'http://www.wikidata.org/entity/Q43605'), ('objName', 'French Open')]
#[('obj', 'http://www.wikidata.org/entity/Q123577'), ('objName', 'US Open')]
#[('obj', 'http://www.wikidata.org/entity/Q41520'), ('objName', 'Wimbledon Championships')]
#[('obj', 'http://www.wikidata.org/entity/Q60874'), ('objName', 'Australian Open')]

# 1) group by yearlyTournament and winner of the yearlyTournament

queryString = """

PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
SELECT ?yearlyTournament ?yearlyTournamentName ?winner ?winnerName (COUNT(*) as ?tot)
WHERE {
   VALUES (?tournament){
       (wd:Q43605)
       (wd:Q123577)
       (wd:Q41520)
       (wd:Q60874)
   }   
   # ?yearlyTournament wdt:P31 ?tournament.
   # ?yearlyTournament wdt:P527 ?subTournament.
   # ?subTournament wdt:P1346 ?winner.
   
   # get the label 
   # ?tournament sc:name ?tournamentName .
   # ?yearlyTournament sc:name ?yearlyTournamentName .
   # ?subTournament sc:name ?subTournamentName.
   # ?winner sc:name ?winnerName.
   # ?winner wdt:P569 ?dob   
}
GROUP BY ?winner ?winnerName ?yearlyTournament ?yearlyTournamentName
LIMIT 20

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('yearlyTournament', 'http://www.wikidata.org/entity/Q99526045'), ('yearlyTournamentName', '2021 French Open'), ('winner', 'http://www.wikidata.org/entity/Q5812'), ('winnerName', 'Novak Djokovic'), ('tot', '1')]
# [('yearlyTournament', 'http://www.wikidata.org/entity/Q1576241'), ('yearlyTournamentName', '1984 US Open'), ('winner', 'http://www.wikidata.org/entity/Q54654'), ('winnerName', 'Pam Shriver'), ('tot', '1')]
# [('yearlyTournament', 'http://www.wikidata.org/entity/Q911810'), ('yearlyTournamentName', '1968 French Open'), ('winner', 'http://www.wikidata.org/entity/Q263134'), ('winnerName', 'Françoise Dürr'), ('tot', '1')]
# [('yearlyTournament', 'http://www.wikidata.org/entity/Q1508020'), ('yearlyTournamentName', '1982 US Open'), ('winner', 'http://www.wikidata.org/entity/Q53400'), ('winnerName', 'Kevin Curren'), ('tot', '2')]
# [('yearlyTournament', 'http://www.wikidata.org/entity/Q2620232'), ('yearlyTournamentName', '1896 U.S. National Championships'), ('winner', 'http://www.wikidata.org/entity/Q467237'), ('winnerName', 'Elisabeth Moore'), ('tot', '1')]
# [('yearlyTournament', 'http://www.wikidata.org/entity/Q2538713'), ('yearlyTournamentName', '1936 French Championships'), ('winner', 'http://www.wikidata.org/entity/Q61136'), ('winnerName', 'Gottfried von Cramm'), ('tot', '1')]
# [('yearlyTournament', 'http://www.wikidata.org/entity/Q28836049'), ('yearlyTournamentName', '2017 US Open'), ('winner', 'http://www.wikidata.org/entity/Q552349'), ('winnerName', 'Jean-Julien Rojer'), ('tot', '1')]
# [('yearlyTournament', 'http://www.wikidata.org/entity/Q549612'), ('yearlyTournamentName', '1966 French Championships'), ('winner', 'http://www.wikidata.org/entity/Q710119'), ('winnerName', 'Tony Roche'), ('tot', '1')]
# [('yearlyTournament', 'http://www.wikidata.org/entity/Q2620515'), ('yearlyTournamentName', '1893 U.S. National Championships'), ('winner', 'http://www.wikidata.org/entity/Q333104'), ('winnerName', 'Aline Terry'), ('tot', '1')]
# [('yearlyTournament', 'http://www.wikidata.org/entity/Q1326081'), ('yearlyTournamentName', '1980 US Open'), ('winner', 'http://www.wikidata.org/entity/Q14286'), ('winnerName', 'Chris Evert'), ('tot', '1')]
# [('yearlyTournament', 'http://www.wikidata.org/entity/Q737905'), ('yearlyTournamentName', '2002 French Open'), ('winner', 'http://www.wikidata.org/entity/Q317828'), ('winnerName', 'Albert Costa'), ('tot', '1')]
# [('yearlyTournament', 'http://www.wikidata.org/entity/Q50391517'), ('yearlyTournamentName', '2018 US Open'), ('winner', 'http://www.wikidata.org/entity/Q53342'), ('winnerName', 'Mike Bryan'), ('tot', '1')]
# [('yearlyTournament', 'http://www.wikidata.org/entity/Q24387175'), ('yearlyTournamentName', '2017 French Open'), ('winner', 'http://www.wikidata.org/entity/Q16224602'), ('winnerName', 'Yui Kamiji'), ('tot', '2')]
# [('yearlyTournament', 'http://www.wikidata.org/entity/Q2620561'), ('yearlyTournamentName', '1892 U.S. National Championships'), ('winner', 'http://www.wikidata.org/entity/Q440851'), ('winnerName', 'Mabel Cahill'), ('tot', '1')]
# [('yearlyTournament', 'http://www.wikidata.org/entity/Q660527'), ('yearlyTournamentName', '1983 French Open'), ('winner', 'http://www.wikidata.org/entity/Q1566777'), ('winnerName', 'Hans Simonsson'), ('tot', '1')]
# [('yearlyTournament', 'http://www.wikidata.org/entity/Q2539662'), ('yearlyTournamentName', '1938 French Championships'), ('winner', 'http://www.wikidata.org/entity/Q273491'), ('winnerName', 'Simonne Mathieu'), ('tot', '1')]
# [('yearlyTournament', 'http://www.wikidata.org/entity/Q832157'), ('yearlyTournamentName', '2003 French Open'), ('winner', 'http://www.wikidata.org/entity/Q53340'), ('winnerName', 'Bob Bryan'), ('tot', '1')]
# [('yearlyTournament', 'http://www.wikidata.org/entity/Q28836049'), ('yearlyTournamentName', '2017 US Open'), ('winner', 'http://www.wikidata.org/entity/Q26951148'), ('winnerName', 'Alfie Hewett'), ('tot', '1')]
# [('yearlyTournament', 'http://www.wikidata.org/entity/Q50391517'), ('yearlyTournamentName', '2018 US Open'), ('winner', 'http://www.wikidata.org/entity/Q41799108'), ('winnerName', 'Wang Xiyu'), ('tot', '1')]
# [('yearlyTournament', 'http://www.wikidata.org/entity/Q268871'), ('yearlyTournamentName', '2004 Wimbledon Championships'), ('winner', 'http://www.wikidata.org/entity/Q310380'), ('winnerName', 'Jonas Björkman'), ('tot', '1')]
# 20

# %%
# write your queries
# Consider the country for sport property of the tennis player (NO Country of citizenship). 
# Return the countries with at least one player who won at least one edition of each Grand Slam (the result set must be a list of country IRI and label).

# [('p', 'http://www.wikidata.org/prop/direct/P1532'), ('name', 'country for sport')]

# P31 ('instance of')
# P527 ('has part')
# P1346 ('winner')

#[('obj', 'http://www.wikidata.org/entity/Q43605'), ('objName', 'French Open')]
#[('obj', 'http://www.wikidata.org/entity/Q123577'), ('objName', 'US Open')]
#[('obj', 'http://www.wikidata.org/entity/Q41520'), ('objName', 'Wimbledon Championships')]
#[('obj', 'http://www.wikidata.org/entity/Q60874'), ('objName', 'Australian Open')]

# 1) group by yearlyTournament and winner of the yearlyTournament
# cheching subtournaments

queryString = """

PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
SELECT DISTINCT ?subTournament ?subTournamentName
WHERE {
   VALUES (?tournament){
       (wd:Q43605)
       (wd:Q123577)
       (wd:Q41520)
       (wd:Q60874)
   }
   # ?yearlyTournament wdt:P31 ?tournament.
   # ?yearlyTournament wdt:P527 ?subTournament.
   # ?subTournament wdt:P1346 ?winner.
   
   # get the label 
   # ?tournament sc:name ?tournamentName .
   # ?yearlyTournament sc:name ?yearlyTournamentName .
   # ?subTournament sc:name ?subTournamentName.
   # ?winner sc:name ?winnerName.
   # ?winner wdt:P569 ?dob   
}
#GROUP BY ?winner ?winnerName ?tournament ?tournamentName
LIMIT 50

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('subTournament', 'http://www.wikidata.org/entity/Q248965'), ('subTournamentName', "2004 Wimbledon Championships – Men's Singles")]
# [('subTournament', 'http://www.wikidata.org/entity/Q3994898'), ('subTournamentName', "2004 Wimbledon Championships – Men's Doubles")]
# [('subTournament', 'http://www.wikidata.org/entity/Q1575133'), ('subTournamentName', "2004 Wimbledon Championships – Women's Doubles")]
# [('subTournament', 'http://www.wikidata.org/entity/Q378546'), ('subTournamentName', "2004 Wimbledon Championships – Women's Singles")]
# [('subTournament', 'http://www.wikidata.org/entity/Q388810'), ('subTournamentName', '2004 Wimbledon Championships - Mixed Doubles')]
# [('subTournament', 'http://www.wikidata.org/entity/Q781612'), ('subTournamentName', "1969 Australian Open – Women's Doubles")]
# [('subTournament', 'http://www.wikidata.org/entity/Q781629'), ('subTournamentName', "1969 Australian Open – Women's Singles")]
# [('subTournament', 'http://www.wikidata.org/entity/Q781620'), ('subTournamentName', '1969 Australian Open – Mixed Doubles')]
# [('subTournament', 'http://www.wikidata.org/entity/Q2364152'), ('subTournamentName', "1969 Australian Open – Men's Doubles")]
# [('subTournament', 'http://www.wikidata.org/entity/Q764694'), ('subTournamentName', "1969 Australian Open – Men's Singles")]
# [('subTournament', 'http://www.wikidata.org/entity/Q3037642'), ('subTournamentName', '2000 US Open – Mixed Doubles')]
# [('subTournament', 'http://www.wikidata.org/entity/Q923940'), ('subTournamentName', "2000 US Open – Men's Singles")]
# [('subTournament', 'http://www.wikidata.org/entity/Q947513'), ('subTournamentName', "2000 US Open – Men's Doubles")]
# [('subTournament', 'http://www.wikidata.org/entity/Q1578492'), ('subTournamentName', "2000 US Open – Women's Singles")]
# [('subTournament', 'http://www.wikidata.org/entity/Q958902'), ('subTournamentName', "US Open 2000 women's doubles")]
# [('subTournament', 'http://www.wikidata.org/entity/Q1455360'), ('subTournamentName', "1983 French Open – Women's Doubles")]
# [('subTournament', 'http://www.wikidata.org/entity/Q1059712'), ('subTournamentName', "1983 French Open – Women's Singles")]
# [('subTournament', 'http://www.wikidata.org/entity/Q3037695'), ('subTournamentName', '1983 French Open – Mixed Doubles')]
# [('subTournament', 'http://www.wikidata.org/entity/Q2714991'), ('subTournamentName', "1983 French Open – Men's Singles")]
# [('subTournament', 'http://www.wikidata.org/entity/Q3883675'), ('subTournamentName', "1983 French Open – Men's Doubles")]
# [('subTournament', 'http://www.wikidata.org/entity/Q543974'), ('subTournamentName', "2004 US Open – Men's Doubles")]
# [('subTournament', 'http://www.wikidata.org/entity/Q1070514'), ('subTournamentName', "2004 US Open – Women's Singles")]
# [('subTournament', 'http://www.wikidata.org/entity/Q1048953'), ('subTournamentName', "2004 US Open – Men's Singles")]
# [('subTournament', 'http://www.wikidata.org/entity/Q4002348'), ('subTournamentName', '2004 US Open – Mixed Doubles')]
# [('subTournament', 'http://www.wikidata.org/entity/Q2404173'), ('subTournamentName', "2004 US Open – Women's Doubles")]
# [('subTournament', 'http://www.wikidata.org/entity/Q1455421'), ('subTournamentName', "2000 French Open – Men's Doubles")]
# [('subTournament', 'http://www.wikidata.org/entity/Q1048966'), ('subTournamentName', "2000 French Open – Men's Singles")]
# [('subTournament', 'http://www.wikidata.org/entity/Q1455413'), ('subTournamentName', "2000 French Open – Women's Doubles")]
# [('subTournament', 'http://www.wikidata.org/entity/Q3037716'), ('subTournamentName', '2000 French Open – Mixed Doubles')]
# [('subTournament', 'http://www.wikidata.org/entity/Q1068835'), ('subTournamentName', "2000 French Open – Women's Singles")]
# [('subTournament', 'http://www.wikidata.org/entity/Q15854755'), ('subTournamentName', "1978 Wimbledon Championships – Men's Doubles")]
# [('subTournament', 'http://www.wikidata.org/entity/Q941235'), ('subTournamentName', "1978 Wimbledon Championships – Men's Singles")]
# [('subTournament', 'http://www.wikidata.org/entity/Q1189922'), ('subTournamentName', "1978 Wimbledon Championships – Women's Singles")]
# [('subTournament', 'http://www.wikidata.org/entity/Q3037785'), ('subTournamentName', '1978 Wimbledon Championships – Mixed Doubles')]
# [('subTournament', 'http://www.wikidata.org/entity/Q2583172'), ('subTournamentName', "1978 Wimbledon Championships – Women's Doubles")]
# [('subTournament', 'http://www.wikidata.org/entity/Q1753809'), ('subTournamentName', "1928 French Championships – Women's Singles")]
# [('subTournament', 'http://www.wikidata.org/entity/Q1752640'), ('subTournamentName', "1928 French Championships – Men's Singles")]
# [('subTournament', 'http://www.wikidata.org/entity/Q17173001'), ('subTournamentName', "2014 Wimbledon Championships – Women's Doubles")]
# [('subTournament', 'http://www.wikidata.org/entity/Q16744746'), ('subTournamentName', "2014 Wimbledon Championships – Women's Singles")]
# [('subTournament', 'http://www.wikidata.org/entity/Q17173009'), ('subTournamentName', '2014 Wimbledon Championships – Mixed Doubles')]
# [('subTournament', 'http://www.wikidata.org/entity/Q16893134'), ('subTournamentName', "2014 Wimbledon Championships – Men's Singles")]
# [('subTournament', 'http://www.wikidata.org/entity/Q17173004'), ('subTournamentName', "2014 Wimbledon Championships – Men's Doubles")]
# [('subTournament', 'http://www.wikidata.org/entity/Q17323949'), ('subTournamentName', "2014 US Open – Women's Singles")]
# [('subTournament', 'http://www.wikidata.org/entity/Q17501579'), ('subTournamentName', '2014 US Open – Mixed Doubles')]
# [('subTournament', 'http://www.wikidata.org/entity/Q17501588'), ('subTournamentName', "2014 US Open – Women's Doubles")]
# [('subTournament', 'http://www.wikidata.org/entity/Q17486716'), ('subTournamentName', "2014 US Open – Girls' Doubles")]
# [('subTournament', 'http://www.wikidata.org/entity/Q17112345'), ('subTournamentName', "2014 US Open – Men's Singles")]
# [('subTournament', 'http://www.wikidata.org/entity/Q17486715'), ('subTournamentName', "2014 US Open – Girls' Singles")]
# [('subTournament', 'http://www.wikidata.org/entity/Q17584888'), ('subTournamentName', "2014 US Open – Men's Doubles")]
# [('subTournament', 'http://www.wikidata.org/entity/Q17735428'), ('subTournamentName', "2014 US Open – Boys' Singles")]
# 50

# %%
# write your queries
# Consider the country for sport property of the tennis player (NO Country of citizenship). 
# Return the countries with at least one player who won at least one edition of each Grand Slam (the result set must be a list of country IRI and label).

# [('p', 'http://www.wikidata.org/prop/direct/P1532'), ('name', 'country for sport')]

# P31 ('instance of')
# P527 ('has part')
# P1346 ('winner')

#[('obj', 'http://www.wikidata.org/entity/Q43605'), ('objName', 'French Open')]
#[('obj', 'http://www.wikidata.org/entity/Q123577'), ('objName', 'US Open')]
#[('obj', 'http://www.wikidata.org/entity/Q41520'), ('objName', 'Wimbledon Championships')]
#[('obj', 'http://www.wikidata.org/entity/Q60874'), ('objName', 'Australian Open')]

# 1) group by yearlyTournament and winner of the yearlyTournament
# cheching subtournaments
# added ordering

queryString = """

PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
SELECT DISTINCT ?subTournament ?subTournamentName
WHERE {
   VALUES (?tournament){
       (wd:Q43605)
       (wd:Q123577)
       (wd:Q41520)
       (wd:Q60874)
   }
   # ?yearlyTournament wdt:P31 ?tournament.
   # ?yearlyTournament wdt:P527 ?subTournament.
   # ?subTournament wdt:P1346 ?winner.
   
   # get the label 
   # ?tournament sc:name ?tournamentName .
   # ?yearlyTournament sc:name ?yearlyTournamentName .
   # ?subTournament sc:name ?subTournamentName.
   # ?winner sc:name ?winnerName.
   # ?winner wdt:P569 ?dob   
}
#GROUP BY ?winner ?winnerName ?tournament ?tournamentName
ORDER BY DESC (?subTournamentName)
LIMIT 50

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('subTournament', 'http://www.wikidata.org/entity/Q958902'), ('subTournamentName', "US Open 2000 women's doubles")]
# [('subTournament', 'http://www.wikidata.org/entity/Q4339659'), ('subTournamentName', 'Australian Open 2007')]
# [('subTournament', 'http://www.wikidata.org/entity/Q92032445'), ('subTournamentName', "2021 Wimbledon Championships – Women's Singles")]
# [('subTournament', 'http://www.wikidata.org/entity/Q92032438'), ('subTournamentName', "2021 Wimbledon Championships – Women's Doubles")]
# [('subTournament', 'http://www.wikidata.org/entity/Q107434675'), ('subTournamentName', "2021 Wimbledon Championships – Wheelchair Women's Singles")]
# [('subTournament', 'http://www.wikidata.org/entity/Q107434679'), ('subTournamentName', "2021 Wimbledon Championships – Wheelchair Women's Doubles")]
# [('subTournament', 'http://www.wikidata.org/entity/Q107379851'), ('subTournamentName', '2021 Wimbledon Championships – Mixed Doubles')]
# [('subTournament', 'http://www.wikidata.org/entity/Q92032464'), ('subTournamentName', "2021 Wimbledon Championships – Men's Singles")]
# [('subTournament', 'http://www.wikidata.org/entity/Q107345665'), ('subTournamentName', "2021 Wimbledon Championships – Men's Doubles")]
# [('subTournament', 'http://www.wikidata.org/entity/Q98811676'), ('subTournamentName', "2021 US Open – Women's Singles")]
# [('subTournament', 'http://www.wikidata.org/entity/Q108436150'), ('subTournamentName', "2021 US Open – Girls' Singles")]
# [('subTournament', 'http://www.wikidata.org/entity/Q108437590'), ('subTournamentName', "2021 US Open – Girls' Doubles")]
# [('subTournament', 'http://www.wikidata.org/entity/Q99526059'), ('subTournamentName', "2021 French Open – Women's Singles")]
# [('subTournament', 'http://www.wikidata.org/entity/Q99756845'), ('subTournamentName', "2021 French Open – Women's Doubles")]
# [('subTournament', 'http://www.wikidata.org/entity/Q99756902'), ('subTournamentName', '2021 French Open – Mixed Doubles')]
# [('subTournament', 'http://www.wikidata.org/entity/Q99526058'), ('subTournamentName', "2021 French Open – Men's Singles")]
# [('subTournament', 'http://www.wikidata.org/entity/Q99756869'), ('subTournamentName', "2021 French Open – Men's Doubles")]
# [('subTournament', 'http://www.wikidata.org/entity/Q107111218'), ('subTournamentName', "2021 French Open – Girls' Singles")]
# [('subTournament', 'http://www.wikidata.org/entity/Q107125108'), ('subTournamentName', "2021 French Open – Girls' Doubles")]
# [('subTournament', 'http://www.wikidata.org/entity/Q107111575'), ('subTournamentName', "2021 French Open – Boys' Singles")]
# [('subTournament', 'http://www.wikidata.org/entity/Q107125095'), ('subTournamentName', "2021 French Open – Boys' Doubles")]
# [('subTournament', 'http://www.wikidata.org/entity/Q83629825'), ('subTournamentName', "2021 Australian Open – Women's Singles")]
# [('subTournament', 'http://www.wikidata.org/entity/Q105353897'), ('subTournamentName', "2021 Australian Open – Women's Doubles")]
# [('subTournament', 'http://www.wikidata.org/entity/Q105433973'), ('subTournamentName', '2021 Australian Open – Mixed Doubles')]
# [('subTournament', 'http://www.wikidata.org/entity/Q83629829'), ('subTournamentName', "2021 Australian Open – Men's Singles")]
# [('subTournament', 'http://www.wikidata.org/entity/Q105357561'), ('subTournamentName', "2021 Australian Open – Men's Doubles")]
# [('subTournament', 'http://www.wikidata.org/entity/Q66399871'), ('subTournamentName', "2020 US Open – Women's Singles")]
# [('subTournament', 'http://www.wikidata.org/entity/Q98729081'), ('subTournamentName', "2020 US Open – Women's Doubles")]
# [('subTournament', 'http://www.wikidata.org/entity/Q99066986'), ('subTournamentName', "2020 US Open – Wheelchair Women's Singles")]
# [('subTournament', 'http://www.wikidata.org/entity/Q99067336'), ('subTournamentName', "2020 US Open – Wheelchair Women's Doubles")]
# [('subTournament', 'http://www.wikidata.org/entity/Q66399443'), ('subTournamentName', "2020 US Open – Men's Singles")]
# [('subTournament', 'http://www.wikidata.org/entity/Q98754894'), ('subTournamentName', "2020 US Open – Men's Doubles")]
# [('subTournament', 'http://www.wikidata.org/entity/Q63367916'), ('subTournamentName', "2020 French Open – Women's Singles")]
# [('subTournament', 'http://www.wikidata.org/entity/Q63367914'), ('subTournamentName', "2020 French Open – Women's Doubles")]
# [('subTournament', 'http://www.wikidata.org/entity/Q100151414'), ('subTournamentName', "2020 French Open – Wheelchair Women's Singles")]
# [('subTournament', 'http://www.wikidata.org/entity/Q100152451'), ('subTournamentName', "2020 French Open – Wheelchair Women's Doubles")]
# [('subTournament', 'http://www.wikidata.org/entity/Q100152531'), ('subTournamentName', '2020 French Open – Wheelchair Quad Singles')]
# [('subTournament', 'http://www.wikidata.org/entity/Q100152559'), ('subTournamentName', '2020 French Open – Wheelchair Quad Doubles')]
# [('subTournament', 'http://www.wikidata.org/entity/Q100152266'), ('subTournamentName', "2020 French Open – Wheelchair Men's Singles")]
# [('subTournament', 'http://www.wikidata.org/entity/Q100152440'), ('subTournamentName', "2020 French Open – Wheelchair Men's Doubles")]
# [('subTournament', 'http://www.wikidata.org/entity/Q63367923'), ('subTournamentName', "2020 French Open – Men's Singles")]
# [('subTournament', 'http://www.wikidata.org/entity/Q63367918'), ('subTournamentName', "2020 French Open – Men's Doubles")]
# [('subTournament', 'http://www.wikidata.org/entity/Q61062114'), ('subTournamentName', "2020 Australian Open – Women's Singles")]
# [('subTournament', 'http://www.wikidata.org/entity/Q61062316'), ('subTournamentName', "2020 Australian Open – Women's Doubles")]
# [('subTournament', 'http://www.wikidata.org/entity/Q83857656'), ('subTournamentName', "2020 Australian Open – Wheelchair Women's Singles")]
# [('subTournament', 'http://www.wikidata.org/entity/Q83897085'), ('subTournamentName', "2020 Australian Open – Wheelchair Women's Doubles")]
# [('subTournament', 'http://www.wikidata.org/entity/Q83895960'), ('subTournamentName', "2020 Australian Open – Wheelchair Men's Singles")]
# [('subTournament', 'http://www.wikidata.org/entity/Q83896517'), ('subTournamentName', "2020 Australian Open – Wheelchair Men's Doubles")]
# [('subTournament', 'http://www.wikidata.org/entity/Q61062516'), ('subTournamentName', '2020 Australian Open – Mixed Doubles')]
# [('subTournament', 'http://www.wikidata.org/entity/Q61062112'), ('subTournamentName', "2020 Australian Open – Men's Singles")]
# 50

# %% [markdown]
# #####  Problem found
# Problem found with initial solution, if I group by winner & only yearlGrandSlam a winner can have more than 4 winning in a year, due to the subTournaments.
# ```
# Goal is to have at most 4 repetition respectively of 4 tournaments of Grand Slam```

# %%
# write your queries
# Consider the country for sport property of the tennis player (NO Country of citizenship). 
# Return the countries with at least one player who won at least one edition of each Grand Slam (the result set must be a list of country IRI and label).

# [('p', 'http://www.wikidata.org/prop/direct/P1532'), ('name', 'country for sport')]

# P31 ('instance of')
# P527 ('has part')
# P1346 ('winner')

#[('obj', 'http://www.wikidata.org/entity/Q43605'), ('objName', 'French Open')]
#[('obj', 'http://www.wikidata.org/entity/Q123577'), ('objName', 'US Open')]
#[('obj', 'http://www.wikidata.org/entity/Q41520'), ('objName', 'Wimbledon Championships')]
#[('obj', 'http://www.wikidata.org/entity/Q60874'), ('objName', 'Australian Open')]

# Q99526059 - 2021 French Open – Women's Singles

# trying to find about 'Women's Singles' from Q99526059

queryString = """

PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
SELECT DISTINCT ?p ?pName ?o
WHERE {
   wd:Q99526059 ?p ?o .
   # get the label 
   # ?p sc:name ?pName.
   #?o sc:name ?oName.
}
LIMIT 50

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner'), ('o', 'http://www.wikidata.org/entity/Q11052500')]
# [('p', 'http://www.wikidata.org/prop/direct/P155'), ('pName', 'follows'), ('o', 'http://www.wikidata.org/entity/Q63367916')]
# [('p', 'http://www.wikidata.org/prop/direct/P156'), ('pName', 'followed by'), ('o', 'http://www.wikidata.org/entity/Q107126330')]
# [('p', 'http://www.wikidata.org/prop/direct/P2094'), ('pName', 'competition class'), ('o', 'http://www.wikidata.org/entity/Q16893403')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('o', 'http://www.wikidata.org/entity/Q46190676')]
# [('p', 'http://www.wikidata.org/prop/direct/P361'), ('pName', 'part of'), ('o', 'http://www.wikidata.org/entity/Q99526045')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('o', 'http://www.wikidata.org/entity/Q106956794')]
# [('p', 'http://www.wikidata.org/prop/direct/P585'), ('pName', 'point in time'), ('o', '2021-01-01T00:00:00Z')]
# [('p', 'http://www.wikidata.org/prop/direct/P641'), ('pName', 'sport'), ('o', 'http://www.wikidata.org/entity/Q847')]
# 9

# %%
# write your queries
# Consider the country for sport property of the tennis player (NO Country of citizenship). 
# Return the countries with at least one player who won at least one edition of each Grand Slam (the result set must be a list of country IRI and label).

# [('p', 'http://www.wikidata.org/prop/direct/P1532'), ('name', 'country for sport')]

# P31 ('instance of')
# P527 ('has part')
# P1346 ('winner')

#[('obj', 'http://www.wikidata.org/entity/Q43605'), ('objName', 'French Open')]
#[('obj', 'http://www.wikidata.org/entity/Q123577'), ('objName', 'US Open')]
#[('obj', 'http://www.wikidata.org/entity/Q41520'), ('objName', 'Wimbledon Championships')]
#[('obj', 'http://www.wikidata.org/entity/Q60874'), ('objName', 'Australian Open')]

# Q99526059 - 2021 French Open – Women's Singles
# Q99526059 --P2094 ('competition class')-> wd:Q16893403 ("women's singles")

# trying to find about 'Women's Singles' from Q99526059

queryString = """

PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
SELECT DISTINCT ?o ?oName
WHERE {
   wd:Q99526059 wdt:P2094 ?o .
   # get the label 
   # ?o sc:name ?oName.
}
LIMIT 50

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('o', 'http://www.wikidata.org/entity/Q16893403'), ('oName', "women's singles")]
# 1

# %%
# write your queries
# Consider the country for sport property of the tennis player (NO Country of citizenship). 
# Return the countries with at least one player who won at least one edition of each Grand Slam (the result set must be a list of country IRI and label).

# [('p', 'http://www.wikidata.org/prop/direct/P1532'), ('name', 'country for sport')]

# P31 ('instance of')
# P527 ('has part')
# P1346 ('winner')

#[('obj', 'http://www.wikidata.org/entity/Q43605'), ('objName', 'French Open')]
#[('obj', 'http://www.wikidata.org/entity/Q123577'), ('objName', 'US Open')]
#[('obj', 'http://www.wikidata.org/entity/Q41520'), ('objName', 'Wimbledon Championships')]
#[('obj', 'http://www.wikidata.org/entity/Q60874'), ('objName', 'Australian Open')]

# Q99526059 - 2021 French Open – Women's Singles

# from above:
#[('subTournament', 'http://www.wikidata.org/entity/Q99526059'), ('subTournamentName', "2021 French Open – Women's Singles")]
#[('subTournament', 'http://www.wikidata.org/entity/Q99756845'), ('subTournamentName', "2021 French Open – Women's Doubles")]
#[('subTournament', 'http://www.wikidata.org/entity/Q99756902'), ('subTournamentName', '2021 French Open – Mixed Doubles')]
#[('subTournament', 'http://www.wikidata.org/entity/Q99526058'), ('subTournamentName', "2021 French Open – Men's Singles")]
#[('subTournament', 'http://www.wikidata.org/entity/Q99756869'), ('subTournamentName', "2021 French Open – Men's Doubles")]
#[('subTournament', 'http://www.wikidata.org/entity/Q107111218'), ('subTournamentName', "2021 French Open – Girls' Singles")]
#[('subTournament', 'http://www.wikidata.org/entity/Q107125108'), ('subTournamentName', "2021 French Open – Girls' Doubles")]
#[('subTournament', 'http://www.wikidata.org/entity/Q107111575'), ('subTournamentName', "2021 French Open – Boys' Singles")]
#[('subTournament', 'http://www.wikidata.org/entity/Q107125095'), ('subTournamentName', "2021 French Open – Boys' Doubles")]

# lets check if they all have --P2094 ('competition class')-> relationship

queryString = """

PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
SELECT DISTINCT ?p ?pName ?o ?oName
WHERE {
    VALUES(?s){
        (wd:Q99526059)
        (wd:Q99756845)
        (wd:Q99756902)
        (wd:Q99526058)
        (wd:Q99756869)
        (wd:Q107111218)
        (wd:Q107125108)
        (wd:Q107111575)
        (wd:Q107125095)
    }
   # ?s ?p ?o .
   # get the label 
   # ?p sc:name ?pName.
   # ?o sc:name ?oName.
}
LIMIT 50

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P2094'), ('pName', 'competition class'), ('o', 'http://www.wikidata.org/entity/Q27907702'), ('oName', "boys' singles")]
# [('p', 'http://www.wikidata.org/prop/direct/P2094'), ('pName', 'competition class'), ('o', 'http://www.wikidata.org/entity/Q27907692'), ('oName', "girls' doubles")]
# [('p', 'http://www.wikidata.org/prop/direct/P2094'), ('pName', 'competition class'), ('o', 'http://www.wikidata.org/entity/Q27907716'), ('oName', "boys' doubles")]
# [('p', 'http://www.wikidata.org/prop/direct/P2094'), ('pName', 'competition class'), ('o', 'http://www.wikidata.org/entity/Q16629853'), ('oName', 'mixed doubles')]
# [('p', 'http://www.wikidata.org/prop/direct/P2094'), ('pName', 'competition class'), ('o', 'http://www.wikidata.org/entity/Q16893403'), ('oName', "women's singles")]
# [('p', 'http://www.wikidata.org/prop/direct/P2094'), ('pName', 'competition class'), ('o', 'http://www.wikidata.org/entity/Q17299348'), ('oName', "women's doubles")]
# [('p', 'http://www.wikidata.org/prop/direct/P641'), ('pName', 'sport'), ('o', 'http://www.wikidata.org/entity/Q847'), ('oName', 'tennis')]
# [('p', 'http://www.wikidata.org/prop/direct/P2094'), ('pName', 'competition class'), ('o', 'http://www.wikidata.org/entity/Q27907674'), ('oName', "girls' singles")]
# [('p', 'http://www.wikidata.org/prop/direct/P2094'), ('pName', 'competition class'), ('o', 'http://www.wikidata.org/entity/Q16893072'), ('oName', "men's singles")]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('o', 'http://www.wikidata.org/entity/Q46190676'), ('oName', 'tennis event')]
# [('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner'), ('o', 'http://www.wikidata.org/entity/Q5812'), ('oName', 'Novak Djokovic')]
# [('p', 'http://www.wikidata.org/prop/direct/P2094'), ('pName', 'competition class'), ('o', 'http://www.wikidata.org/entity/Q17299700'), ('oName', "men's doubles")]
# [('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner'), ('o', 'http://www.wikidata.org/entity/Q2093033'), ('oName', 'Pierre-Hugues Herbert')]
# [('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner'), ('o', 'http://www.wikidata.org/entity/Q11052500'), ('oName', 'Barbora Krejčíková')]
# [('p', 'http://www.wikidata.org/prop/direct/P155'), ('pName', 'follows'), ('o', 'http://www.wikidata.org/entity/Q63367918'), ('oName', "2020 French Open – Men's Doubles")]
# [('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner'), ('o', 'http://www.wikidata.org/entity/Q67088022'), ('oName', 'Alex Eala')]
# [('p', 'http://www.wikidata.org/prop/direct/P361'), ('pName', 'part of'), ('o', 'http://www.wikidata.org/entity/Q99526045'), ('oName', '2021 French Open')]
# [('p', 'http://www.wikidata.org/prop/direct/P156'), ('pName', 'followed by'), ('o', 'http://www.wikidata.org/entity/Q107126330'), ('oName', "2022 French Open – Women's Singles")]
# [('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner'), ('o', 'http://www.wikidata.org/entity/Q34115005'), ('oName', 'Desirae Krawczyk')]
# [('p', 'http://www.wikidata.org/prop/direct/P155'), ('pName', 'follows'), ('o', 'http://www.wikidata.org/entity/Q63367914'), ('oName', "2020 French Open – Women's Doubles")]
# [('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner'), ('o', 'http://www.wikidata.org/entity/Q106354932'), ('oName', 'Linda Nosková')]
# [('p', 'http://www.wikidata.org/prop/direct/P156'), ('pName', 'followed by'), ('o', 'http://www.wikidata.org/entity/Q107126332'), ('oName', "2022 French Open – Men's Doubles")]
# [('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner'), ('o', 'http://www.wikidata.org/entity/Q107207693'), ('oName', 'Arthur Fils')]
# [('p', 'http://www.wikidata.org/prop/direct/P155'), ('pName', 'follows'), ('o', 'http://www.wikidata.org/entity/Q63367916'), ('oName', "2020 French Open – Women's Singles")]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('o', 'http://www.wikidata.org/entity/Q106952396'), ('oName', "2021 French Open – Men's Singles Qualifying")]
# [('p', 'http://www.wikidata.org/prop/direct/P156'), ('pName', 'followed by'), ('o', 'http://www.wikidata.org/entity/Q107126329'), ('oName', "2022 French Open – Men's Singles")]
# [('p', 'http://www.wikidata.org/prop/direct/P155'), ('pName', 'follows'), ('o', 'http://www.wikidata.org/entity/Q63367923'), ('oName', "2020 French Open – Men's Singles")]
# [('p', 'http://www.wikidata.org/prop/direct/P156'), ('pName', 'followed by'), ('o', 'http://www.wikidata.org/entity/Q107126331'), ('oName', "2022 French Open – Women's Doubles")]
# [('p', 'http://www.wikidata.org/prop/direct/P156'), ('pName', 'followed by'), ('o', 'http://www.wikidata.org/entity/Q107126333'), ('oName', '2022 French Open – Mixed Doubles')]
# [('p', 'http://www.wikidata.org/prop/direct/P155'), ('pName', 'follows'), ('o', 'http://www.wikidata.org/entity/Q64083436'), ('oName', '2019 French Open – Mixed Doubles')]
# [('p', 'http://www.wikidata.org/prop/direct/P1346'), ('pName', 'winner'), ('o', 'http://www.wikidata.org/entity/Q107205896'), ('oName', 'Luca Van Assche')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('o', 'http://www.wikidata.org/entity/Q106956794'), ('oName', "2021 French Open – Women's Singles Qualifying")]
# 32

# %%
# write your queries
# Consider the country for sport property of the tennis player (NO Country of citizenship). 
# Return the countries with at least one player who won at least one edition of each Grand Slam (the result set must be a list of country IRI and label).

# [('p', 'http://www.wikidata.org/prop/direct/P1532'), ('name', 'country for sport')]

# P31 ('instance of')
# P527 ('has part')
# P1346 ('winner')

#[('obj', 'http://www.wikidata.org/entity/Q43605'), ('objName', 'French Open')]
#[('obj', 'http://www.wikidata.org/entity/Q123577'), ('objName', 'US Open')]
#[('obj', 'http://www.wikidata.org/entity/Q41520'), ('objName', 'Wimbledon Championships')]
#[('obj', 'http://www.wikidata.org/entity/Q60874'), ('objName', 'Australian Open')]

# Q99526059 - 2021 French Open – Women's Singles
# P2094 'competition class'

# lets check if they all have --P2094 ('competition class')-> relationship

queryString = """

PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
SELECT DISTINCT ?o ?oName
WHERE {
    VALUES(?s){
        (wd:Q99526059)
        (wd:Q99756845)
        (wd:Q99756902)
        (wd:Q99526058)
        (wd:Q99756869)
        (wd:Q107111218)
        (wd:Q107125108)
        (wd:Q107111575)
        (wd:Q107125095)
    }
   # ?s wdt:P2094 ?o .
   # ?o sc:name ?oName.
}
LIMIT 50

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('o', 'http://www.wikidata.org/entity/Q27907702'), ('oName', "boys' singles")]
# [('o', 'http://www.wikidata.org/entity/Q27907692'), ('oName', "girls' doubles")]
# [('o', 'http://www.wikidata.org/entity/Q27907716'), ('oName', "boys' doubles")]
# [('o', 'http://www.wikidata.org/entity/Q16629853'), ('oName', 'mixed doubles')]
# [('o', 'http://www.wikidata.org/entity/Q16893403'), ('oName', "women's singles")]
# [('o', 'http://www.wikidata.org/entity/Q17299348'), ('oName', "women's doubles")]
# [('o', 'http://www.wikidata.org/entity/Q27907674'), ('oName', "girls' singles")]
# [('o', 'http://www.wikidata.org/entity/Q16893072'), ('oName', "men's singles")]
# [('o', 'http://www.wikidata.org/entity/Q17299700'), ('oName', "men's doubles")]
# 9

# %% [markdown]
# ##### So now lets try grouping by competition class,
# ```
# then possible solution could be to check if someone has won in all 4 tournament in the same competition class```

# %%
# write your queries
# Consider the country for sport property of the tennis player (NO Country of citizenship). 
# Return the countries with at least one player who won at least one edition of each Grand Slam (the result set must be a list of country IRI and label).

# [('p', 'http://www.wikidata.org/prop/direct/P1532'), ('name', 'country for sport')]

# P31 ('instance of')
# P527 ('has part')
# P1346 ('winner')

#[('obj', 'http://www.wikidata.org/entity/Q43605'), ('objName', 'French Open')]
#[('obj', 'http://www.wikidata.org/entity/Q123577'), ('objName', 'US Open')]
#[('obj', 'http://www.wikidata.org/entity/Q41520'), ('objName', 'Wimbledon Championships')]
#[('obj', 'http://www.wikidata.org/entity/Q60874'), ('objName', 'Australian Open')]

# Q99526059 - 2021 French Open – Women's Singles

#P2094' competition class'

# checking if in 2021 someone has won all edition of each Grand Slam in the same category 

queryString = """

PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
SELECT ?o ?oName
WHERE {
    VALUES(?s){
        (wd:Q92032445) #subTournamentName', "2021 Wimbledon Championships – Women's Singles")]
        (wd:Q92032438) #subTournamentName', "2021 Wimbledon Championships – Women's Doubles")]
        (wd:Q107434675) #subTournamentName', "2021 Wimbledon Championships – Wheelchair Women's Singles")]
        (wd:Q107434679) #subTournamentName', "2021 Wimbledon Championships – Wheelchair Women's Doubles")]
        (wd:Q107379851) #subTournamentName', '2021 Wimbledon Championships – Mixed Doubles')]
        (wd:Q92032464) #subTournamentName', "2021 Wimbledon Championships – Men's Singles")]
        (wd:Q107345665) #subTournamentName', "2021 Wimbledon Championships – Men's Doubles")]
        (wd:Q98811676) #subTournamentName', "2021 US Open – Women's Singles")]
        (wd:Q108436150) #subTournamentName', "2021 US Open – Girls' Singles")]
        (wd:Q108437590) #subTournamentName', "2021 US Open – Girls' Doubles")]
        (wd:Q99526059) #subTournamentName', "2021 French Open – Women's Singles")]
        (wd:Q99756845) #subTournamentName', "2021 French Open – Women's Doubles")]
        (wd:Q99756902) #subTournamentName', '2021 French Open – Mixed Doubles')]
        (wd:Q99526058) #subTournamentName', "2021 French Open – Men's Singles")]
        (wd:Q99756869) #subTournamentName', "2021 French Open – Men's Doubles")]
        (wd:Q107111218) #subTournamentName', "2021 French Open – Girls' Singles")]
        (wd:Q107125108) #subTournamentName', "2021 French Open – Girls' Doubles")]
        (wd:Q107111575) #subTournamentName', "2021 French Open – Boys' Singles")]
        (wd:Q107125095) #subTournamentName', "2021 French Open – Boys' Doubles")]
        (wd:Q83629825) #subTournamentName', "2021 Australian Open – Women's Singles")]
        (wd:Q105353897) #subTournamentName', "2021 Australian Open – Women's Doubles")]
        (wd:Q105433973) #subTournamentName', '2021 Australian Open – Mixed Doubles')]
        (wd:Q83629829) #subTournamentName', "2021 Australian Open – Men's Singles")]
        (wd:Q105357561) #subTournamentName', "2021 Australian Open – Men's Doubles")]
    }
   # ?s wdt:P2094 ?o .
   # ?o sc:name ?oName.
}
LIMIT 50

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('o', 'http://www.wikidata.org/entity/Q27907702'), ('oName', "boys' singles")]
# [('o', 'http://www.wikidata.org/entity/Q27907692'), ('oName', "girls' doubles")]
# [('o', 'http://www.wikidata.org/entity/Q27907692'), ('oName', "girls' doubles")]
# [('o', 'http://www.wikidata.org/entity/Q27907716'), ('oName', "boys' doubles")]
# [('o', 'http://www.wikidata.org/entity/Q16629853'), ('oName', 'mixed doubles')]
# [('o', 'http://www.wikidata.org/entity/Q16629853'), ('oName', 'mixed doubles')]
# [('o', 'http://www.wikidata.org/entity/Q16629853'), ('oName', 'mixed doubles')]
# [('o', 'http://www.wikidata.org/entity/Q16893403'), ('oName', "women's singles")]
# [('o', 'http://www.wikidata.org/entity/Q16893403'), ('oName', "women's singles")]
# [('o', 'http://www.wikidata.org/entity/Q16893403'), ('oName', "women's singles")]
# [('o', 'http://www.wikidata.org/entity/Q16893403'), ('oName', "women's singles")]
# [('o', 'http://www.wikidata.org/entity/Q17299348'), ('oName', "women's doubles")]
# [('o', 'http://www.wikidata.org/entity/Q17299348'), ('oName', "women's doubles")]
# [('o', 'http://www.wikidata.org/entity/Q17299348'), ('oName', "women's doubles")]
# [('o', 'http://www.wikidata.org/entity/Q50211929'), ('oName', "wheelchair tennis women's singles")]
# [('o', 'http://www.wikidata.org/entity/Q27907674'), ('oName', "girls' singles")]
# [('o', 'http://www.wikidata.org/entity/Q27907674'), ('oName', "girls' singles")]
# [('o', 'http://www.wikidata.org/entity/Q16893072'), ('oName', "men's singles")]
# [('o', 'http://www.wikidata.org/entity/Q16893072'), ('oName', "men's singles")]
# [('o', 'http://www.wikidata.org/entity/Q16893072'), ('oName', "men's singles")]
# [('o', 'http://www.wikidata.org/entity/Q17299700'), ('oName', "men's doubles")]
# [('o', 'http://www.wikidata.org/entity/Q17299700'), ('oName', "men's doubles")]
# [('o', 'http://www.wikidata.org/entity/Q17299700'), ('oName', "men's doubles")]
# [('o', 'http://www.wikidata.org/entity/Q50211939'), ('oName', "wheelchair tennis women's doubles")]
# 24

# %%
# write your queries
# Consider the country for sport property of the tennis player (NO Country of citizenship). 
# Return the countries with at least one player who won at least one edition of each Grand Slam (the result set must be a list of country IRI and label).

# [('p', 'http://www.wikidata.org/prop/direct/P1532'), ('name', 'country for sport')]

# P31 ('instance of')
# P527 ('has part')
# P1346 ('winner')

#[('obj', 'http://www.wikidata.org/entity/Q43605'), ('objName', 'French Open')]
#[('obj', 'http://www.wikidata.org/entity/Q123577'), ('objName', 'US Open')]
#[('obj', 'http://www.wikidata.org/entity/Q41520'), ('objName', 'Wimbledon Championships')]
#[('obj', 'http://www.wikidata.org/entity/Q60874'), ('objName', 'Australian Open')]

# Q99526059 - 2021 French Open – Women's Singles

#P2094' competition class'

# 1) checking if in 2021 someone has won all edition of each Grand Slam in the same category 
# 1.1) checking categories of 2021 GS tournament 

queryString = """

PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
SELECT ?o ?oName (COUNT(*) AS ?tot)
WHERE {
    VALUES(?s){
        (wd:Q92032445) #subTournamentName', "2021 Wimbledon Championships – Women's Singles")]
        (wd:Q92032438) #subTournamentName', "2021 Wimbledon Championships – Women's Doubles")]
        (wd:Q107434675) #subTournamentName', "2021 Wimbledon Championships – Wheelchair Women's Singles")]
        (wd:Q107434679) #subTournamentName', "2021 Wimbledon Championships – Wheelchair Women's Doubles")]
        (wd:Q107379851) #subTournamentName', '2021 Wimbledon Championships – Mixed Doubles')]
        (wd:Q92032464) #subTournamentName', "2021 Wimbledon Championships – Men's Singles")]
        (wd:Q107345665) #subTournamentName', "2021 Wimbledon Championships – Men's Doubles")]
        (wd:Q98811676) #subTournamentName', "2021 US Open – Women's Singles")]
        (wd:Q108436150) #subTournamentName', "2021 US Open – Girls' Singles")]
        (wd:Q108437590) #subTournamentName', "2021 US Open – Girls' Doubles")]
        (wd:Q99526059) #subTournamentName', "2021 French Open – Women's Singles")]
        (wd:Q99756845) #subTournamentName', "2021 French Open – Women's Doubles")]
        (wd:Q99756902) #subTournamentName', '2021 French Open – Mixed Doubles')]
        (wd:Q99526058) #subTournamentName', "2021 French Open – Men's Singles")]
        (wd:Q99756869) #subTournamentName', "2021 French Open – Men's Doubles")]
        (wd:Q107111218) #subTournamentName', "2021 French Open – Girls' Singles")]
        (wd:Q107125108) #subTournamentName', "2021 French Open – Girls' Doubles")]
        (wd:Q107111575) #subTournamentName', "2021 French Open – Boys' Singles")]
        (wd:Q107125095) #subTournamentName', "2021 French Open – Boys' Doubles")]
        (wd:Q83629825) #subTournamentName', "2021 Australian Open – Women's Singles")]
        (wd:Q105353897) #subTournamentName', "2021 Australian Open – Women's Doubles")]
        (wd:Q105433973) #subTournamentName', '2021 Australian Open – Mixed Doubles')]
        (wd:Q83629829) #subTournamentName', "2021 Australian Open – Men's Singles")]
        (wd:Q105357561) #subTournamentName', "2021 Australian Open – Men's Doubles")]
    }
   # ?s wdt:P2094 ?o .
   # ?o sc:name ?oName.
}
GROUP BY ?o ?oName
LIMIT 50

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('o', 'http://www.wikidata.org/entity/Q27907692'), ('oName', "girls' doubles"), ('tot', '2')]
# [('o', 'http://www.wikidata.org/entity/Q16629853'), ('oName', 'mixed doubles'), ('tot', '3')]
# [('o', 'http://www.wikidata.org/entity/Q16893403'), ('oName', "women's singles"), ('tot', '4')]
# [('o', 'http://www.wikidata.org/entity/Q27907674'), ('oName', "girls' singles"), ('tot', '2')]
# [('o', 'http://www.wikidata.org/entity/Q16893072'), ('oName', "men's singles"), ('tot', '3')]
# [('o', 'http://www.wikidata.org/entity/Q27907702'), ('oName', "boys' singles"), ('tot', '1')]
# [('o', 'http://www.wikidata.org/entity/Q17299348'), ('oName', "women's doubles"), ('tot', '3')]
# [('o', 'http://www.wikidata.org/entity/Q50211929'), ('oName', "wheelchair tennis women's singles"), ('tot', '1')]
# [('o', 'http://www.wikidata.org/entity/Q50211939'), ('oName', "wheelchair tennis women's doubles"), ('tot', '1')]
# [('o', 'http://www.wikidata.org/entity/Q27907716'), ('oName', "boys' doubles"), ('tot', '1')]
# [('o', 'http://www.wikidata.org/entity/Q17299700'), ('oName', "men's doubles"), ('tot', '3')]
# 11

# %%
# write your queries
# Consider the country for sport property of the tennis player (NO Country of citizenship). 
# Return the countries with at least one player who won at least one edition of each Grand Slam (the result set must be a list of country IRI and label).

# [('p', 'http://www.wikidata.org/prop/direct/P1532'), ('name', 'country for sport')]

# P31 ('instance of')
# P527 ('has part')
# P1346 ('winner')

#[('obj', 'http://www.wikidata.org/entity/Q43605'), ('objName', 'French Open')]
#[('obj', 'http://www.wikidata.org/entity/Q123577'), ('objName', 'US Open')]
#[('obj', 'http://www.wikidata.org/entity/Q41520'), ('objName', 'Wimbledon Championships')]
#[('obj', 'http://www.wikidata.org/entity/Q60874'), ('objName', 'Australian Open')]

# Q99526059 - 2021 French Open – Women's Singles

#P2094' competition class'

# 1) checking if in 2021 someone has won all edition of each Grand Slam in the same category 
# 1.1) checking categories of 2021 GS tournament 
queryString = """

PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
SELECT ?o ?oName (COUNT(*) AS ?tot)
WHERE {
    VALUES(?s){
        (wd:Q92032445) #subTournamentName', "2021 Wimbledon Championships – Women's Singles")]
        (wd:Q92032438) #subTournamentName', "2021 Wimbledon Championships – Women's Doubles")]
        (wd:Q107434675) #subTournamentName', "2021 Wimbledon Championships – Wheelchair Women's Singles")]
        (wd:Q107434679) #subTournamentName', "2021 Wimbledon Championships – Wheelchair Women's Doubles")]
        (wd:Q107379851) #subTournamentName', '2021 Wimbledon Championships – Mixed Doubles')]
        (wd:Q92032464) #subTournamentName', "2021 Wimbledon Championships – Men's Singles")]
        (wd:Q107345665) #subTournamentName', "2021 Wimbledon Championships – Men's Doubles")]
        (wd:Q98811676) #subTournamentName', "2021 US Open – Women's Singles")]
        (wd:Q108436150) #subTournamentName', "2021 US Open – Girls' Singles")]
        (wd:Q108437590) #subTournamentName', "2021 US Open – Girls' Doubles")]
        (wd:Q99526059) #subTournamentName', "2021 French Open – Women's Singles")]
        (wd:Q99756845) #subTournamentName', "2021 French Open – Women's Doubles")]
        (wd:Q99756902) #subTournamentName', '2021 French Open – Mixed Doubles')]
        (wd:Q99526058) #subTournamentName', "2021 French Open – Men's Singles")]
        (wd:Q99756869) #subTournamentName', "2021 French Open – Men's Doubles")]
        (wd:Q107111218) #subTournamentName', "2021 French Open – Girls' Singles")]
        (wd:Q107125108) #subTournamentName', "2021 French Open – Girls' Doubles")]
        (wd:Q107111575) #subTournamentName', "2021 French Open – Boys' Singles")]
        (wd:Q107125095) #subTournamentName', "2021 French Open – Boys' Doubles")]
        (wd:Q83629825) #subTournamentName', "2021 Australian Open – Women's Singles")]
        (wd:Q105353897) #subTournamentName', "2021 Australian Open – Women's Doubles")]
        (wd:Q105433973) #subTournamentName', '2021 Australian Open – Mixed Doubles')]
        (wd:Q83629829) #subTournamentName', "2021 Australian Open – Men's Singles")]
        (wd:Q105357561) #subTournamentName', "2021 Australian Open – Men's Doubles")]
    }
   # ?s wdt:P2094 ?o .
   # ?o sc:name ?oName.
}
GROUP BY ?o ?oName
HAVING (COUNT(*) >= 4)
LIMIT 50

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('o', 'http://www.wikidata.org/entity/Q16893403'), ('oName', "women's singles"), ('tot', '4')]
# 1

# %% [markdown]
# ##### Attention: only 'wommen's singles' competition has been played in all four tournaments of Grand Slam 2021

# %%
# write your queries
# Consider the country for sport property of the tennis player (NO Country of citizenship). 
# Return the countries with at least one player who won at least one edition of each Grand Slam (the result set must be a list of country IRI and label).

# [('p', 'http://www.wikidata.org/prop/direct/P1532'), ('name', 'country for sport')]

# P31 ('instance of')
# P527 ('has part')
# P1346 ('winner')

#[('obj', 'http://www.wikidata.org/entity/Q43605'), ('objName', 'French Open')]
#[('obj', 'http://www.wikidata.org/entity/Q123577'), ('objName', 'US Open')]
#[('obj', 'http://www.wikidata.org/entity/Q41520'), ('objName', 'Wimbledon Championships')]
#[('obj', 'http://www.wikidata.org/entity/Q60874'), ('objName', 'Australian Open')]

# Q99526059 - 2021 French Open – Women's Singles

#P2094' competition class'

# 1) checking if in 2021 someone has won all edition of each Grand Slam in the same category 
# 1.1) checking categories of 2021 GS tournament 
# 1.2) finding the winners of 2021 GS tournament in each category

queryString = """

PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
SELECT DISTINCT ?sName ?o ?oName ?winner ?winnerName
WHERE {
    VALUES(?s){
        (wd:Q92032445) #subTournamentName', "2021 Wimbledon Championships – Women's Singles")]
        (wd:Q92032438) #subTournamentName', "2021 Wimbledon Championships – Women's Doubles")]
        (wd:Q107434675) #subTournamentName', "2021 Wimbledon Championships – Wheelchair Women's Singles")]
        (wd:Q107434679) #subTournamentName', "2021 Wimbledon Championships – Wheelchair Women's Doubles")]
        (wd:Q107379851) #subTournamentName', '2021 Wimbledon Championships – Mixed Doubles')]
        (wd:Q92032464) #subTournamentName', "2021 Wimbledon Championships – Men's Singles")]
        (wd:Q107345665) #subTournamentName', "2021 Wimbledon Championships – Men's Doubles")]
        (wd:Q98811676) #subTournamentName', "2021 US Open – Women's Singles")]
        (wd:Q108436150) #subTournamentName', "2021 US Open – Girls' Singles")]
        (wd:Q108437590) #subTournamentName', "2021 US Open – Girls' Doubles")]
        (wd:Q99526059) #subTournamentName', "2021 French Open – Women's Singles")]
        (wd:Q99756845) #subTournamentName', "2021 French Open – Women's Doubles")]
        (wd:Q99756902) #subTournamentName', '2021 French Open – Mixed Doubles')]
        (wd:Q99526058) #subTournamentName', "2021 French Open – Men's Singles")]
        (wd:Q99756869) #subTournamentName', "2021 French Open – Men's Doubles")]
        (wd:Q107111218) #subTournamentName', "2021 French Open – Girls' Singles")]
        (wd:Q107125108) #subTournamentName', "2021 French Open – Girls' Doubles")]
        (wd:Q107111575) #subTournamentName', "2021 French Open – Boys' Singles")]
        (wd:Q107125095) #subTournamentName', "2021 French Open – Boys' Doubles")]
        (wd:Q83629825) #subTournamentName', "2021 Australian Open – Women's Singles")]
        (wd:Q105353897) #subTournamentName', "2021 Australian Open – Women's Doubles")]
        (wd:Q105433973) #subTournamentName', '2021 Australian Open – Mixed Doubles')]
        (wd:Q83629829) #subTournamentName', "2021 Australian Open – Men's Singles")]
        (wd:Q105357561) #subTournamentName', "2021 Australian Open – Men's Doubles")]
    }
   # ?s wdt:P2094 ?o;
      wdt:P1346 ?winner.
   
   # ?s sc:name ?sName.  
   # ?o sc:name ?oName.  
   # ?winner sc:name ?winnerName.
}
LIMIT 50

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('sName', "2021 French Open – Boys' Singles"), ('o', 'http://www.wikidata.org/entity/Q27907702'), ('oName', "boys' singles"), ('winner', 'http://www.wikidata.org/entity/Q107205896'), ('winnerName', 'Luca Van Assche')]
# [('sName', "2021 US Open – Girls' Doubles"), ('o', 'http://www.wikidata.org/entity/Q27907692'), ('oName', "girls' doubles"), ('winner', 'http://www.wikidata.org/entity/Q66309318'), ('winnerName', 'Robin Montgomery')]
# [('sName', "2021 French Open – Girls' Doubles"), ('o', 'http://www.wikidata.org/entity/Q27907692'), ('oName', "girls' doubles"), ('winner', 'http://www.wikidata.org/entity/Q67088022'), ('winnerName', 'Alex Eala')]
# [('sName', "2021 French Open – Boys' Doubles"), ('o', 'http://www.wikidata.org/entity/Q27907716'), ('oName', "boys' doubles"), ('winner', 'http://www.wikidata.org/entity/Q107207693'), ('winnerName', 'Arthur Fils')]
# [('sName', '2021 French Open – Mixed Doubles'), ('o', 'http://www.wikidata.org/entity/Q16629853'), ('oName', 'mixed doubles'), ('winner', 'http://www.wikidata.org/entity/Q34115005'), ('winnerName', 'Desirae Krawczyk')]
# [('sName', '2021 Wimbledon Championships – Mixed Doubles'), ('o', 'http://www.wikidata.org/entity/Q16629853'), ('oName', 'mixed doubles'), ('winner', 'http://www.wikidata.org/entity/Q14558117'), ('winnerName', 'Neal Skupski')]
# [('sName', '2021 Australian Open – Mixed Doubles'), ('o', 'http://www.wikidata.org/entity/Q16629853'), ('oName', 'mixed doubles'), ('winner', 'http://www.wikidata.org/entity/Q11052500'), ('winnerName', 'Barbora Krejčíková')]
# [('sName', '2021 Wimbledon Championships – Mixed Doubles'), ('o', 'http://www.wikidata.org/entity/Q16629853'), ('oName', 'mixed doubles'), ('winner', 'http://www.wikidata.org/entity/Q34115005'), ('winnerName', 'Desirae Krawczyk')]
# [('sName', "2021 US Open – Women's Singles"), ('o', 'http://www.wikidata.org/entity/Q16893403'), ('oName', "women's singles"), ('winner', 'http://www.wikidata.org/entity/Q64849968'), ('winnerName', 'Emma Raducanu')]
# [('sName', "2021 French Open – Women's Singles"), ('o', 'http://www.wikidata.org/entity/Q16893403'), ('oName', "women's singles"), ('winner', 'http://www.wikidata.org/entity/Q11052500'), ('winnerName', 'Barbora Krejčíková')]
# [('sName', "2021 Wimbledon Championships – Women's Singles"), ('o', 'http://www.wikidata.org/entity/Q16893403'), ('oName', "women's singles"), ('winner', 'http://www.wikidata.org/entity/Q84056'), ('winnerName', 'Ashleigh Barty')]
# [('sName', "2021 Australian Open – Women's Singles"), ('o', 'http://www.wikidata.org/entity/Q16893403'), ('oName', "women's singles"), ('winner', 'http://www.wikidata.org/entity/Q17466583'), ('winnerName', 'Naomi Osaka')]
# [('sName', "2021 Wimbledon Championships – Women's Doubles"), ('o', 'http://www.wikidata.org/entity/Q17299348'), ('oName', "women's doubles"), ('winner', 'http://www.wikidata.org/entity/Q232566'), ('winnerName', 'Hsieh Su-wei')]
# [('sName', "2021 Wimbledon Championships – Women's Doubles"), ('o', 'http://www.wikidata.org/entity/Q17299348'), ('oName', "women's doubles"), ('winner', 'http://www.wikidata.org/entity/Q17381675'), ('winnerName', 'Elise Mertens')]
# [('sName', "2021 French Open – Women's Doubles"), ('o', 'http://www.wikidata.org/entity/Q17299348'), ('oName', "women's doubles"), ('winner', 'http://www.wikidata.org/entity/Q11052500'), ('winnerName', 'Barbora Krejčíková')]
# [('sName', "2021 Australian Open – Women's Doubles"), ('o', 'http://www.wikidata.org/entity/Q17299348'), ('oName', "women's doubles"), ('winner', 'http://www.wikidata.org/entity/Q17381675'), ('winnerName', 'Elise Mertens')]
# [('sName', "2021 Wimbledon Championships – Wheelchair Women's Singles"), ('o', 'http://www.wikidata.org/entity/Q50211929'), ('oName', "wheelchair tennis women's singles"), ('winner', 'http://www.wikidata.org/entity/Q24574661'), ('winnerName', 'Diede de Groot')]
# [('sName', "2021 French Open – Girls' Singles"), ('o', 'http://www.wikidata.org/entity/Q27907674'), ('oName', "girls' singles"), ('winner', 'http://www.wikidata.org/entity/Q106354932'), ('winnerName', 'Linda Nosková')]
# [('sName', "2021 US Open – Girls' Singles"), ('o', 'http://www.wikidata.org/entity/Q27907674'), ('oName', "girls' singles"), ('winner', 'http://www.wikidata.org/entity/Q66309318'), ('winnerName', 'Robin Montgomery')]
# [('sName', "2021 Australian Open – Men's Singles"), ('o', 'http://www.wikidata.org/entity/Q16893072'), ('oName', "men's singles"), ('winner', 'http://www.wikidata.org/entity/Q5812'), ('winnerName', 'Novak Djokovic')]
# [('sName', "2021 French Open – Men's Singles"), ('o', 'http://www.wikidata.org/entity/Q16893072'), ('oName', "men's singles"), ('winner', 'http://www.wikidata.org/entity/Q5812'), ('winnerName', 'Novak Djokovic')]
# [('sName', "2021 Wimbledon Championships – Men's Singles"), ('o', 'http://www.wikidata.org/entity/Q16893072'), ('oName', "men's singles"), ('winner', 'http://www.wikidata.org/entity/Q5812'), ('winnerName', 'Novak Djokovic')]
# [('sName', "2021 Wimbledon Championships – Men's Doubles"), ('o', 'http://www.wikidata.org/entity/Q17299700'), ('oName', "men's doubles"), ('winner', 'http://www.wikidata.org/entity/Q7035585'), ('winnerName', 'Nikola Mektić')]
# [('sName', "2021 Australian Open – Men's Doubles"), ('o', 'http://www.wikidata.org/entity/Q17299700'), ('oName', "men's doubles"), ('winner', 'http://www.wikidata.org/entity/Q324515'), ('winnerName', 'Ivan Dodig')]
# [('sName', "2021 Wimbledon Championships – Men's Doubles"), ('o', 'http://www.wikidata.org/entity/Q17299700'), ('oName', "men's doubles"), ('winner', 'http://www.wikidata.org/entity/Q1588571'), ('winnerName', 'Mate Pavić')]
# [('sName', "2021 French Open – Men's Doubles"), ('o', 'http://www.wikidata.org/entity/Q17299700'), ('oName', "men's doubles"), ('winner', 'http://www.wikidata.org/entity/Q2093033'), ('winnerName', 'Pierre-Hugues Herbert')]
# [('sName', "2021 Wimbledon Championships – Wheelchair Women's Doubles"), ('o', 'http://www.wikidata.org/entity/Q50211939'), ('oName', "wheelchair tennis women's doubles"), ('winner', 'http://www.wikidata.org/entity/Q16224602'), ('winnerName', 'Yui Kamiji')]
# [('sName', "2021 Wimbledon Championships – Wheelchair Women's Doubles"), ('o', 'http://www.wikidata.org/entity/Q50211939'), ('oName', "wheelchair tennis women's doubles"), ('winner', 'http://www.wikidata.org/entity/Q6277349'), ('winnerName', 'Jordanne Whiley')]
# 28

# %%
# write your queries
# Consider the country for sport property of the tennis player (NO Country of citizenship). 
# Return the countries with at least one player who won at least one edition of each Grand Slam (the result set must be a list of country IRI and label).

# [('p', 'http://www.wikidata.org/prop/direct/P1532'), ('name', 'country for sport')]

# P31 ('instance of')
# P527 ('has part')
# P1346 ('winner')

#[('obj', 'http://www.wikidata.org/entity/Q43605'), ('objName', 'French Open')]
#[('obj', 'http://www.wikidata.org/entity/Q123577'), ('objName', 'US Open')]
#[('obj', 'http://www.wikidata.org/entity/Q41520'), ('objName', 'Wimbledon Championships')]
#[('obj', 'http://www.wikidata.org/entity/Q60874'), ('objName', 'Australian Open')]

# 1) checking if in all seasons if someone has won all edition of each Grand Slam in the same category 
# 1.2) finding the winners of each GS tournament in each category
queryString = """

PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
SELECT DISTINCT ?winner ?winnerName ?competitionClass ?yearlyTournamentName (COUNT(*) as ?tot)
WHERE {
   VALUES (?tournament){
       (wd:Q43605)
       (wd:Q123577)
       (wd:Q41520)
       (wd:Q60874)
   }
   # ?yearlyTournament wdt:P31 ?tournament.
   # ?yearlyTournament wdt:P527 ?subTournament.
   # ?subTournament wdt:P1346 ?winner;
                   wdt:P2094 ?competitionClass.
   
   # ?winner wdt:P569 ?dob.
   
   # get the label 
   # ?tournament sc:name ?tournamentName .
   # ?yearlyTournament sc:name ?yearlyTournamentName .
   # ?subTournament sc:name ?subTournamentName.
   # ?winner sc:name ?winnerName.
   # ?competitionClass sc:name ?competitionClassName.
}
#GROUP BY ?winner ?winnerName ?competitionClassName ?yearlyTournamentName
ORDER BY DESC (?tot)
LIMIT 50

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('winner', 'http://www.wikidata.org/entity/Q725525'), ('winnerName', 'Ken Fletcher'), ('competitionClass', 'http://www.wikidata.org/entity/Q16629853'), ('yearlyTournamentName', '1963 Australian Championships'), ('tot', '2')]
# [('winner', 'http://www.wikidata.org/entity/Q261983'), ('winnerName', 'Nancye Wynne Bolton'), ('competitionClass', 'http://www.wikidata.org/entity/Q17299348'), ('yearlyTournamentName', '1951 Australian Championships'), ('tot', '2')]
# [('winner', 'http://www.wikidata.org/entity/Q506606'), ('winnerName', 'Mark Edmondson'), ('competitionClass', 'http://www.wikidata.org/entity/Q16893072'), ('yearlyTournamentName', '1976 Australian Open'), ('tot', '2')]
# [('winner', 'http://www.wikidata.org/entity/Q261983'), ('winnerName', 'Nancye Wynne Bolton'), ('competitionClass', 'http://www.wikidata.org/entity/Q16629853'), ('yearlyTournamentName', '1946 Australian Championships'), ('tot', '2')]
# [('winner', 'http://www.wikidata.org/entity/Q374047'), ('winnerName', 'Adrian Quist'), ('competitionClass', 'http://www.wikidata.org/entity/Q17299700'), ('yearlyTournamentName', '1937 Australian Championships'), ('tot', '2')]
# [('winner', 'http://www.wikidata.org/entity/Q261983'), ('winnerName', 'Nancye Wynne Bolton'), ('competitionClass', 'http://www.wikidata.org/entity/Q16629853'), ('yearlyTournamentName', '1947 Australian Championships'), ('tot', '2')]
# [('winner', 'http://www.wikidata.org/entity/Q261983'), ('winnerName', 'Nancye Wynne Bolton'), ('competitionClass', 'http://www.wikidata.org/entity/Q16893403'), ('yearlyTournamentName', '1951 Australian Championships'), ('tot', '2')]
# [('winner', 'http://www.wikidata.org/entity/Q506606'), ('winnerName', 'Mark Edmondson'), ('competitionClass', 'http://www.wikidata.org/entity/Q17299700'), ('yearlyTournamentName', '1983 Australian Open'), ('tot', '2')]
# [('winner', 'http://www.wikidata.org/entity/Q261983'), ('winnerName', 'Nancye Wynne Bolton'), ('competitionClass', 'http://www.wikidata.org/entity/Q16893403'), ('yearlyTournamentName', '1947 Australian Championships'), ('tot', '2')]
# [('winner', 'http://www.wikidata.org/entity/Q261983'), ('winnerName', 'Nancye Wynne Bolton'), ('competitionClass', 'http://www.wikidata.org/entity/Q17299348'), ('yearlyTournamentName', '1947 Australian Championships'), ('tot', '2')]
# [('winner', 'http://www.wikidata.org/entity/Q374047'), ('winnerName', 'Adrian Quist'), ('competitionClass', 'http://www.wikidata.org/entity/Q16893072'), ('yearlyTournamentName', '1948 Australian Championships'), ('tot', '2')]
# [('winner', 'http://www.wikidata.org/entity/Q506606'), ('winnerName', 'Mark Edmondson'), ('competitionClass', 'http://www.wikidata.org/entity/Q17299700'), ('yearlyTournamentName', '1981 Australian Open'), ('tot', '2')]
# [('winner', 'http://www.wikidata.org/entity/Q261983'), ('winnerName', 'Nancye Wynne Bolton'), ('competitionClass', 'http://www.wikidata.org/entity/Q16629853'), ('yearlyTournamentName', '1940 Australian Championships'), ('tot', '2')]
# [('winner', 'http://www.wikidata.org/entity/Q506606'), ('winnerName', 'Mark Edmondson'), ('competitionClass', 'http://www.wikidata.org/entity/Q17299700'), ('yearlyTournamentName', '1980 Australian Open'), ('tot', '2')]
# [('winner', 'http://www.wikidata.org/entity/Q261983'), ('winnerName', 'Nancye Wynne Bolton'), ('competitionClass', 'http://www.wikidata.org/entity/Q17299348'), ('yearlyTournamentName', '1949 Australian Championships'), ('tot', '2')]
# [('winner', 'http://www.wikidata.org/entity/Q261983'), ('winnerName', 'Nancye Wynne Bolton'), ('competitionClass', 'http://www.wikidata.org/entity/Q16893403'), ('yearlyTournamentName', '1946 Australian Championships'), ('tot', '2')]
# [('winner', 'http://www.wikidata.org/entity/Q374047'), ('winnerName', 'Adrian Quist'), ('competitionClass', 'http://www.wikidata.org/entity/Q17299700'), ('yearlyTournamentName', '1936 Australian Championships'), ('tot', '2')]
# [('winner', 'http://www.wikidata.org/entity/Q725525'), ('winnerName', 'Ken Fletcher'), ('competitionClass', 'http://www.wikidata.org/entity/Q16629853'), ('yearlyTournamentName', '1964 Australian Championships'), ('tot', '2')]
# [('winner', 'http://www.wikidata.org/entity/Q261983'), ('winnerName', 'Nancye Wynne Bolton'), ('competitionClass', 'http://www.wikidata.org/entity/Q16629853'), ('yearlyTournamentName', '1948 Australian Championships'), ('tot', '2')]
# [('winner', 'http://www.wikidata.org/entity/Q261983'), ('winnerName', 'Nancye Wynne Bolton'), ('competitionClass', 'http://www.wikidata.org/entity/Q16893403'), ('yearlyTournamentName', '1937 Australian Championships'), ('tot', '2')]
# [('winner', 'http://www.wikidata.org/entity/Q261983'), ('winnerName', 'Nancye Wynne Bolton'), ('competitionClass', 'http://www.wikidata.org/entity/Q16893403'), ('yearlyTournamentName', '1940 Australian Championships'), ('tot', '2')]
# [('winner', 'http://www.wikidata.org/entity/Q374047'), ('winnerName', 'Adrian Quist'), ('competitionClass', 'http://www.wikidata.org/entity/Q16893072'), ('yearlyTournamentName', '1940 Australian Championships'), ('tot', '2')]
# [('winner', 'http://www.wikidata.org/entity/Q261983'), ('winnerName', 'Nancye Wynne Bolton'), ('competitionClass', 'http://www.wikidata.org/entity/Q16893403'), ('yearlyTournamentName', '1948 Australian Championships'), ('tot', '2')]
# [('winner', 'http://www.wikidata.org/entity/Q374047'), ('winnerName', 'Adrian Quist'), ('competitionClass', 'http://www.wikidata.org/entity/Q16893072'), ('yearlyTournamentName', '1936 Australian Championships'), ('tot', '2')]
# [('winner', 'http://www.wikidata.org/entity/Q261983'), ('winnerName', 'Nancye Wynne Bolton'), ('competitionClass', 'http://www.wikidata.org/entity/Q17299348'), ('yearlyTournamentName', '1948 Australian Championships'), ('tot', '2')]
# [('winner', 'http://www.wikidata.org/entity/Q273594'), ('winnerName', 'Ellen Hansell'), ('competitionClass', 'http://www.wikidata.org/entity/Q16893403'), ('yearlyTournamentName', '1887 U.S. National Championships'), ('tot', '2')]
# [('winner', 'http://www.wikidata.org/entity/Q506606'), ('winnerName', 'Mark Edmondson'), ('competitionClass', 'http://www.wikidata.org/entity/Q17299700'), ('yearlyTournamentName', '1985 French Open'), ('tot', '2')]
# [('winner', 'http://www.wikidata.org/entity/Q134720'), ('winnerName', 'Martina Hingis'), ('competitionClass', 'http://www.wikidata.org/entity/Q16629853'), ('yearlyTournamentName', '2016 French Open'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q54537'), ('winnerName', 'Bethanie Mattek-Sands'), ('competitionClass', 'http://www.wikidata.org/entity/Q16629853'), ('yearlyTournamentName', '2018 US Open'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q39263365'), ('winnerName', 'Cori Gauff'), ('competitionClass', 'http://www.wikidata.org/entity/Q27907692'), ('yearlyTournamentName', '2018 US Open'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q67200158'), ('winnerName', 'Oksana Selekhmeteva'), ('competitionClass', 'http://www.wikidata.org/entity/Q27907692'), ('yearlyTournamentName', '2019 US Open'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q234624'), ('winnerName', 'Latisha Chan'), ('competitionClass', 'http://www.wikidata.org/entity/Q16629853'), ('yearlyTournamentName', '2018 French Open'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q39263365'), ('winnerName', 'Cori Gauff'), ('competitionClass', 'http://www.wikidata.org/entity/Q27907674'), ('yearlyTournamentName', '2018 French Open'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q189542'), ('winnerName', 'Stefan Edberg'), ('competitionClass', 'http://www.wikidata.org/entity/Q17299700'), ('yearlyTournamentName', '1987 US Open'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q26951148'), ('winnerName', 'Alfie Hewett'), ('competitionClass', 'http://www.wikidata.org/entity/Q50211935'), ('yearlyTournamentName', '2020 French Open'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q64746203'), ('winnerName', 'Matheus Pucinelli de Almeida'), ('competitionClass', 'http://www.wikidata.org/entity/Q27907716'), ('yearlyTournamentName', '2019 French Open'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q54545'), ('winnerName', 'Martina Navratilova'), ('competitionClass', 'http://www.wikidata.org/entity/Q17299348'), ('yearlyTournamentName', '1984 French Open'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q2446649'), ('winnerName', 'Daria Gavrilova'), ('competitionClass', 'http://www.wikidata.org/entity/Q27907674'), ('yearlyTournamentName', '2010 US Open'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q54527'), ('winnerName', 'Billie Jean King'), ('competitionClass', 'http://www.wikidata.org/entity/Q17299348'), ('yearlyTournamentName', '1978 US Open'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q453061'), ('winnerName', 'Bertha Townsend'), ('competitionClass', 'http://www.wikidata.org/entity/Q16893403'), ('yearlyTournamentName', '1888 U.S. National Championships'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q228559'), ('winnerName', 'Evonne Goolagong Cawley'), ('competitionClass', 'http://www.wikidata.org/entity/Q16629853'), ('yearlyTournamentName', '1972 French Open'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q11662'), ('winnerName', 'Steffi Graf'), ('competitionClass', 'http://www.wikidata.org/entity/Q16893403'), ('yearlyTournamentName', '1996 French Open'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q227389'), ('winnerName', 'Zsuzsa Körmöczy'), ('competitionClass', 'http://www.wikidata.org/entity/Q16893403'), ('yearlyTournamentName', '1958 French Championships'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q229831'), ('winnerName', 'Nathalie Dechy'), ('competitionClass', 'http://www.wikidata.org/entity/Q16629853'), ('yearlyTournamentName', '2007 French Open'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q455136'), ('winnerName', 'Anders Järryd'), ('competitionClass', 'http://www.wikidata.org/entity/Q17299700'), ('yearlyTournamentName', '1991 French Open'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q188080'), ('winnerName', 'Arantxa Sánchez Vicario'), ('competitionClass', 'http://www.wikidata.org/entity/Q16629853'), ('yearlyTournamentName', '1990 French Open'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q502583'), ('winnerName', 'Andrei Olhovskiy'), ('competitionClass', 'http://www.wikidata.org/entity/Q16629853'), ('yearlyTournamentName', '1993 French Open'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q62174'), ('winnerName', 'Hilde Krahwinkel Sperling'), ('competitionClass', 'http://www.wikidata.org/entity/Q16893403'), ('yearlyTournamentName', '1937 French Championships'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q435255'), ('winnerName', 'Shirley Brasher'), ('competitionClass', 'http://www.wikidata.org/entity/Q16893403'), ('yearlyTournamentName', '1957 French Championships'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q453061'), ('winnerName', 'Bertha Townsend'), ('competitionClass', 'http://www.wikidata.org/entity/Q16893403'), ('yearlyTournamentName', '1889 U.S. National Championships'), ('tot', '1')]
# 50

# %%
# write your queries
# Consider the country for sport property of the tennis player (NO Country of citizenship). 
# Return the countries with at least one player who won at least one edition of each Grand Slam (the result set must be a list of country IRI and label).

# [('p', 'http://www.wikidata.org/prop/direct/P1532'), ('name', 'country for sport')]

# P31 ('instance of')
# P527 ('has part')
# P1346 ('winner')

#[('obj', 'http://www.wikidata.org/entity/Q43605'), ('objName', 'French Open')]
#[('obj', 'http://www.wikidata.org/entity/Q123577'), ('objName', 'US Open')]
#[('obj', 'http://www.wikidata.org/entity/Q41520'), ('objName', 'Wimbledon Championships')]
#[('obj', 'http://www.wikidata.org/entity/Q60874'), ('objName', 'Australian Open')]

# 1) checking if in all seasons if someone has won all edition of each Grand Slam in the same category 
# 1.2) finding the winners of each GS tournament in each category
#    + competitionClassName
#    + LIMIT 20

queryString = """

PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
SELECT DISTINCT ?winnerName ?competitionClassName ?yearlyTournamentName (COUNT(*) as ?tot)
WHERE {
   VALUES (?tournament){
       (wd:Q43605)
       (wd:Q123577)
       (wd:Q41520)
       (wd:Q60874)
   }
   # ?yearlyTournament wdt:P31 ?tournament.
   # ?yearlyTournament wdt:P527 ?subTournament.
   # ?subTournament wdt:P1346 ?winner;
                   wdt:P2094 ?competitionClass.
   
   # ?winner wdt:P569 ?dob.
   
   # get the label 
   # ?tournament sc:name ?tournamentName .
   # ?yearlyTournament sc:name ?yearlyTournamentName .
   # ?subTournament sc:name ?subTournamentName.
   # ?winner sc:name ?winnerName.
   # ?competitionClass sc:name ?competitionClassName.
}
#GROUP BY ?winner ?winnerName ?competitionClassName ?yearlyTournamentName
ORDER BY DESC (?tot)
LIMIT 20

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('winnerName', 'Mark Edmondson'), ('competitionClassName', "men's doubles"), ('yearlyTournamentName', '1980 Australian Open'), ('tot', '2')]
# [('winnerName', 'Mark Edmondson'), ('competitionClassName', "men's doubles"), ('yearlyTournamentName', '1985 French Open'), ('tot', '2')]
# [('winnerName', 'Nancye Wynne Bolton'), ('competitionClassName', "women's singles"), ('yearlyTournamentName', '1946 Australian Championships'), ('tot', '2')]
# [('winnerName', 'Nancye Wynne Bolton'), ('competitionClassName', "women's singles"), ('yearlyTournamentName', '1940 Australian Championships'), ('tot', '2')]
# [('winnerName', 'Nancye Wynne Bolton'), ('competitionClassName', "women's doubles"), ('yearlyTournamentName', '1948 Australian Championships'), ('tot', '2')]
# [('winnerName', 'Nancye Wynne Bolton'), ('competitionClassName', 'mixed doubles'), ('yearlyTournamentName', '1948 Australian Championships'), ('tot', '2')]
# [('winnerName', 'Adrian Quist'), ('competitionClassName', "men's doubles"), ('yearlyTournamentName', '1936 Australian Championships'), ('tot', '2')]
# [('winnerName', 'Nancye Wynne Bolton'), ('competitionClassName', 'mixed doubles'), ('yearlyTournamentName', '1940 Australian Championships'), ('tot', '2')]
# [('winnerName', 'Ellen Hansell'), ('competitionClassName', "women's singles"), ('yearlyTournamentName', '1887 U.S. National Championships'), ('tot', '2')]
# [('winnerName', 'Adrian Quist'), ('competitionClassName', "men's doubles"), ('yearlyTournamentName', '1937 Australian Championships'), ('tot', '2')]
# [('winnerName', 'Adrian Quist'), ('competitionClassName', "men's singles"), ('yearlyTournamentName', '1936 Australian Championships'), ('tot', '2')]
# [('winnerName', 'Adrian Quist'), ('competitionClassName', "men's singles"), ('yearlyTournamentName', '1940 Australian Championships'), ('tot', '2')]
# [('winnerName', 'Nancye Wynne Bolton'), ('competitionClassName', "women's doubles"), ('yearlyTournamentName', '1947 Australian Championships'), ('tot', '2')]
# [('winnerName', 'Nancye Wynne Bolton'), ('competitionClassName', "women's doubles"), ('yearlyTournamentName', '1951 Australian Championships'), ('tot', '2')]
# [('winnerName', 'Mark Edmondson'), ('competitionClassName', "men's singles"), ('yearlyTournamentName', '1976 Australian Open'), ('tot', '2')]
# [('winnerName', 'Nancye Wynne Bolton'), ('competitionClassName', "women's singles"), ('yearlyTournamentName', '1937 Australian Championships'), ('tot', '2')]
# [('winnerName', 'Nancye Wynne Bolton'), ('competitionClassName', 'mixed doubles'), ('yearlyTournamentName', '1947 Australian Championships'), ('tot', '2')]
# [('winnerName', 'Mark Edmondson'), ('competitionClassName', "men's doubles"), ('yearlyTournamentName', '1983 Australian Open'), ('tot', '2')]
# [('winnerName', 'Nancye Wynne Bolton'), ('competitionClassName', "women's singles"), ('yearlyTournamentName', '1951 Australian Championships'), ('tot', '2')]
# [('winnerName', 'Mark Edmondson'), ('competitionClassName', "men's doubles"), ('yearlyTournamentName', '1981 Australian Open'), ('tot', '2')]
# 20

# %%
# write your queries
# Consider the country for sport property of the tennis player (NO Country of citizenship). 
# Return the countries with at least one player who won at least one edition of each Grand Slam (the result set must be a list of country IRI and label).

# [('p', 'http://www.wikidata.org/prop/direct/P1532'), ('name', 'country for sport')]

# P31 ('instance of')
# P527 ('has part')
# P1346 ('winner')

#[('obj', 'http://www.wikidata.org/entity/Q43605'), ('objName', 'French Open')]
#[('obj', 'http://www.wikidata.org/entity/Q123577'), ('objName', 'US Open')]
#[('obj', 'http://www.wikidata.org/entity/Q41520'), ('objName', 'Wimbledon Championships')]
#[('obj', 'http://www.wikidata.org/entity/Q60874'), ('objName', 'Australian Open')]

# 1) checking if in all seasons if someone has won all edition of each Grand Slam in the same category 
# 1.2) finding the winners of each GS tournament in each category
#    + competitionClassName
#    + LIMIT 20
#    + year

queryString = """

PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
SELECT DISTINCT ?winnerName ?competitionClassName ?year (COUNT(*) as ?tot)
WHERE {
   VALUES (?tournament){
       (wd:Q43605)
       (wd:Q123577)
       (wd:Q41520)
       (wd:Q60874)
   }
   # ?yearlyTournament wdt:P31 ?tournament.
   # ?yearlyTournament wdt:P527 ?subTournament.
   # ?subTournament wdt:P1346 ?winner;
                   wdt:P2094 ?competitionClass.
   
   # ?winner wdt:P569 ?dob.
   
   # get the label 
   # ?tournament sc:name ?tournamentName .
   # ?yearlyTournament sc:name ?yearlyTournamentName .
   # ?subTournament sc:name ?subTournamentName.
   # ?winner sc:name ?winnerName.
   # ?competitionClass sc:name ?competitionClassName.
   
   BIND(SUBSTR(?yearlyTournamentName,0,5) as ?year)
}
#GROUP BY ?winner ?winnerName ?competitionClassName ?year
ORDER BY DESC (?tot)
LIMIT 20

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('winnerName', 'Steffi Graf'), ('competitionClassName', "women's singles"), ('year', '1988 '), ('tot', '4')]
# [('winnerName', 'Diede de Groot'), ('competitionClassName', "wheelchair tennis women's doubles"), ('year', '2019 '), ('tot', '4')]
# [('winnerName', 'Bob Bryan'), ('competitionClassName', "men's doubles"), ('year', '2013 '), ('tot', '3')]
# [('winnerName', 'Martina Navratilova'), ('competitionClassName', "women's singles"), ('year', '1983 '), ('tot', '3')]
# [('winnerName', 'Martina Hingis'), ('competitionClassName', "women's doubles"), ('year', '1998 '), ('tot', '3')]
# [('winnerName', 'Jacco Eltingh'), ('competitionClassName', "men's doubles"), ('year', '1998 '), ('tot', '3')]
# [('winnerName', 'Steffi Graf'), ('competitionClassName', "women's singles"), ('year', '1995 '), ('tot', '3')]
# [('winnerName', 'Serena Williams'), ('competitionClassName', "women's doubles"), ('year', '2009 '), ('tot', '3')]
# [('winnerName', 'Leander Paes'), ('competitionClassName', 'mixed doubles'), ('year', '2015 '), ('tot', '3')]
# [('winnerName', 'Gigi Fernández'), ('competitionClassName', "women's doubles"), ('year', '1994 '), ('tot', '3')]
# [('winnerName', 'Mats Wilander'), ('competitionClassName', "men's singles"), ('year', '1988 '), ('tot', '3')]
# [('winnerName', 'Yui Kamiji'), ('competitionClassName', "wheelchair tennis women's singles"), ('year', '2017 '), ('tot', '3')]
# [('winnerName', 'Novak Djokovic'), ('competitionClassName', "men's singles"), ('year', '2015 '), ('tot', '3')]
# [('winnerName', 'Natasha Zvereva'), ('competitionClassName', "women's doubles"), ('year', '1992 '), ('tot', '3')]
# [('winnerName', 'Gigi Fernández'), ('competitionClassName', "women's doubles"), ('year', '1992 '), ('tot', '3')]
# [('winnerName', 'Jana Novotná'), ('competitionClassName', "women's doubles"), ('year', '1990 '), ('tot', '3')]
# [('winnerName', 'Bob Hewitt'), ('competitionClassName', 'mixed doubles'), ('year', '1979 '), ('tot', '3')]
# [('winnerName', 'Martina Navratilova'), ('competitionClassName', "women's doubles"), ('year', '1982 '), ('tot', '3')]
# [('winnerName', 'Roger Federer'), ('competitionClassName', "men's singles"), ('year', '2004 '), ('tot', '3')]
# [('winnerName', 'Serena Williams'), ('competitionClassName', "women's singles"), ('year', '2015 '), ('tot', '3')]
# 20

# %%
# write your queries
# Consider the country for sport property of the tennis player (NO Country of citizenship). 
# Return the countries with at least one player who won at least one edition of each Grand Slam (the result set must be a list of country IRI and label).

# [('p', 'http://www.wikidata.org/prop/direct/P1532'), ('name', 'country for sport')]

# P31 ('instance of')
# P527 ('has part')
# P1346 ('winner')

#[('obj', 'http://www.wikidata.org/entity/Q43605'), ('objName', 'French Open')]
#[('obj', 'http://www.wikidata.org/entity/Q123577'), ('objName', 'US Open')]
#[('obj', 'http://www.wikidata.org/entity/Q41520'), ('objName', 'Wimbledon Championships')]
#[('obj', 'http://www.wikidata.org/entity/Q60874'), ('objName', 'Australian Open')]

# 1) checking if in all seasons if someone has won all edition of each Grand Slam in the same category 
# 1.2) finding the winners of each GS tournament in each category
#    + competitionClassName
#    + LIMIT 20
#    ! checking if year is correct

queryString = """

PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
SELECT DISTINCT ?winnerName ?competitionClassName ?year (COUNT(*) as ?tot)
WHERE {
   VALUES (?tournament){
       (wd:Q43605)
       (wd:Q123577)
       (wd:Q41520)
       (wd:Q60874)
   }
   # ?yearlyTournament wdt:P31 ?tournament.
   # ?yearlyTournament wdt:P527 ?subTournament.
   # ?subTournament wdt:P1346 ?winner;
                   wdt:P2094 ?competitionClass.
   
   # ?winner wdt:P569 ?dob.
   
   # get the label 
   # ?tournament sc:name ?tournamentName .
   # ?yearlyTournament sc:name ?yearlyTournamentName .
   # ?subTournament sc:name ?subTournamentName.
   # ?winner sc:name ?winnerName.
   # ?competitionClass sc:name ?competitionClassName.
   
   BIND(xsd:gYear(SUBSTR(?yearlyTournamentName,0,4)) as ?year)
}
#GROUP BY ?winner ?winnerName ?competitionClassName ?year
ORDER BY DESC (?tot)
LIMIT 20

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('winnerName', 'Steffi Graf'), ('competitionClassName', "women's singles"), ('year', '1988-01-01'), ('tot', '4')]
# [('winnerName', 'Diede de Groot'), ('competitionClassName', "wheelchair tennis women's doubles"), ('year', '2019-01-01'), ('tot', '4')]
# [('winnerName', 'Rod Laver'), ('competitionClassName', "men's singles"), ('year', '1962-01-01'), ('tot', '3')]
# [('winnerName', 'Martina Navratilova'), ('competitionClassName', 'mixed doubles'), ('year', '1985-01-01'), ('tot', '3')]
# [('winnerName', 'Maureen Connolly'), ('competitionClassName', "women's singles"), ('year', '1953-01-01'), ('tot', '3')]
# [('winnerName', 'Natasha Zvereva'), ('competitionClassName', "women's doubles"), ('year', '1994-01-01'), ('tot', '3')]
# [('winnerName', 'Gigi Fernández'), ('competitionClassName', "women's doubles"), ('year', '1994-01-01'), ('tot', '3')]
# [('winnerName', 'Diede de Groot'), ('competitionClassName', "wheelchair tennis women's singles"), ('year', '2019-01-01'), ('tot', '3')]
# [('winnerName', 'Bob Hewitt'), ('competitionClassName', 'mixed doubles'), ('year', '1979-01-01'), ('tot', '3')]
# [('winnerName', 'Martina Navratilova'), ('competitionClassName', "women's doubles"), ('year', '1983-01-01'), ('tot', '3')]
# [('winnerName', 'Yui Kamiji'), ('competitionClassName', "wheelchair tennis women's singles"), ('year', '2017-01-01'), ('tot', '3')]
# [('winnerName', 'Venus Williams'), ('competitionClassName', "women's doubles"), ('year', '2009-01-01'), ('tot', '3')]
# [('winnerName', 'Jacco Eltingh'), ('competitionClassName', "men's doubles"), ('year', '1998-01-01'), ('tot', '3')]
# [('winnerName', 'Martina Hingis'), ('competitionClassName', 'mixed doubles'), ('year', '2015-01-01'), ('tot', '3')]
# [('winnerName', 'Virginia Ruano Pascual'), ('competitionClassName', "women's doubles"), ('year', '2004-01-01'), ('tot', '3')]
# [('winnerName', 'Bob Bryan'), ('competitionClassName', "men's doubles"), ('year', '2013-01-01'), ('tot', '3')]
# [('winnerName', 'Steffi Graf'), ('competitionClassName', "women's singles"), ('year', '1995-01-01'), ('tot', '3')]
# [('winnerName', 'Diede de Groot'), ('competitionClassName', "wheelchair tennis women's singles"), ('year', '2018-01-01'), ('tot', '3')]
# [('winnerName', 'Novak Djokovic'), ('competitionClassName', "men's singles"), ('year', '2021-01-01'), ('tot', '3')]
# [('winnerName', 'Martina Navratilova'), ('competitionClassName', "women's doubles"), ('year', '1982-01-01'), ('tot', '3')]
# 20

# %%
# write your queries
# Consider the country for sport property of the tennis player (NO Country of citizenship). 
# Return the countries with at least one player who won at least one edition of each Grand Slam (the result set must be a list of country IRI and label).

# [('p', 'http://www.wikidata.org/prop/direct/P1532'), ('name', 'country for sport')]

# P31 ('instance of')
# P527 ('has part')
# P1346 ('winner')

#[('obj', 'http://www.wikidata.org/entity/Q43605'), ('objName', 'French Open')]
#[('obj', 'http://www.wikidata.org/entity/Q123577'), ('objName', 'US Open')]
#[('obj', 'http://www.wikidata.org/entity/Q41520'), ('objName', 'Wimbledon Championships')]
#[('obj', 'http://www.wikidata.org/entity/Q60874'), ('objName', 'Australian Open')]

# 1) checking if in all seasons if someone has won all edition of each Grand Slam in the same category 
# 1.2) finding the winners of each GS tournament in each category
#    + competitionClassName
#    + LIMIT 20
#    + ok year is correct
queryString = """

PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
SELECT DISTINCT ?winnerName ?competitionClassName ?year (COUNT(*) as ?tot)
WHERE {
   VALUES (?tournament){
       (wd:Q43605)
       (wd:Q123577)
       (wd:Q41520)
       (wd:Q60874)
   }
   # ?yearlyTournament wdt:P31 ?tournament.
   # ?yearlyTournament wdt:P527 ?subTournament.
   # ?subTournament wdt:P1346 ?winner;
                   wdt:P2094 ?competitionClass.
   
   # ?winner wdt:P569 ?dob.
   
   # get the label 
   # ?tournament sc:name ?tournamentName .
   # ?yearlyTournament sc:name ?yearlyTournamentName .
   # ?subTournament sc:name ?subTournamentName.
   # ?winner sc:name ?winnerName.
   # ?competitionClass sc:name ?competitionClassName.
   
   BIND(xsd:integer(SUBSTR(?yearlyTournamentName,0,4)) as ?year)
}
#GROUP BY ?winner ?winnerName ?competitionClassName ?year
ORDER BY DESC (?tot)
LIMIT 20

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('winnerName', 'Steffi Graf'), ('competitionClassName', "women's singles"), ('year', '1988'), ('tot', '4')]
# [('winnerName', 'Diede de Groot'), ('competitionClassName', "wheelchair tennis women's doubles"), ('year', '2019'), ('tot', '4')]
# [('winnerName', 'Serena Williams'), ('competitionClassName', "women's doubles"), ('year', '2009'), ('tot', '3')]
# [('winnerName', 'Martina Hingis'), ('competitionClassName', 'mixed doubles'), ('year', '2015'), ('tot', '3')]
# [('winnerName', 'Leander Paes'), ('competitionClassName', 'mixed doubles'), ('year', '2015'), ('tot', '3')]
# [('winnerName', 'Virginia Ruano Pascual'), ('competitionClassName', "women's doubles"), ('year', '2004'), ('tot', '3')]
# [('winnerName', 'Bob Hewitt'), ('competitionClassName', 'mixed doubles'), ('year', '1979'), ('tot', '3')]
# [('winnerName', 'Martina Navratilova'), ('competitionClassName', "women's doubles"), ('year', '1982'), ('tot', '3')]
# [('winnerName', 'Natasha Zvereva'), ('competitionClassName', "women's doubles"), ('year', '1994'), ('tot', '3')]
# [('winnerName', 'Gigi Fernández'), ('competitionClassName', "women's doubles"), ('year', '1994'), ('tot', '3')]
# [('winnerName', 'Gigi Fernández'), ('competitionClassName', "women's doubles"), ('year', '1992'), ('tot', '3')]
# [('winnerName', 'Diede de Groot'), ('competitionClassName', "wheelchair tennis women's singles"), ('year', '2019'), ('tot', '3')]
# [('winnerName', 'Serena Williams'), ('competitionClassName', "women's singles"), ('year', '2015'), ('tot', '3')]
# [('winnerName', 'Novak Djokovic'), ('competitionClassName', "men's singles"), ('year', '2015'), ('tot', '3')]
# [('winnerName', 'Martina Navratilova'), ('competitionClassName', "women's doubles"), ('year', '1987'), ('tot', '3')]
# [('winnerName', 'Novak Djokovic'), ('competitionClassName', "men's singles"), ('year', '2021'), ('tot', '3')]
# [('winnerName', 'Jacco Eltingh'), ('competitionClassName', "men's doubles"), ('year', '1998'), ('tot', '3')]
# [('winnerName', 'Diede de Groot'), ('competitionClassName', "wheelchair tennis women's singles"), ('year', '2018'), ('tot', '3')]
# [('winnerName', 'Roger Federer'), ('competitionClassName', "men's singles"), ('year', '2004'), ('tot', '3')]
# [('winnerName', 'Rod Laver'), ('competitionClassName', "men's singles"), ('year', '1962'), ('tot', '3')]
# 20

# %%
# write your queries
# Consider the country for sport property of the tennis player (NO Country of citizenship). 
# Return the countries with at least one player who won at least one edition of each Grand Slam (the result set must be a list of country IRI and label).

# [('p', 'http://www.wikidata.org/prop/direct/P1532'), ('name', 'country for sport')]

# P31 ('instance of')
# P527 ('has part')
# P1346 ('winner')

#[('obj', 'http://www.wikidata.org/entity/Q43605'), ('objName', 'French Open')]
#[('obj', 'http://www.wikidata.org/entity/Q123577'), ('objName', 'US Open')]
#[('obj', 'http://www.wikidata.org/entity/Q41520'), ('objName', 'Wimbledon Championships')]
#[('obj', 'http://www.wikidata.org/entity/Q60874'), ('objName', 'Australian Open')]

# 1) checking if in all seasons if someone has won all edition of each Grand Slam in the same category 
# 1.2) finding the winners of each GS tournament in each category
#    + competitionClassName
#    + !LIMIT 50
#    + ok year is correct
#    + GROUPING & ORDER BY year
#    + HAVING 

queryString = """

PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
SELECT DISTINCT ?winnerName ?competitionClassName ?year (COUNT(*) as ?tot)
WHERE {
   VALUES (?tournament){
       (wd:Q43605)
       (wd:Q123577)
       (wd:Q41520)
       (wd:Q60874)
   }
   # ?yearlyTournament wdt:P31 ?tournament.
   # ?yearlyTournament wdt:P527 ?subTournament.
   # ?subTournament wdt:P1346 ?winner;
                   wdt:P2094 ?competitionClass.
   
   # ?winner wdt:P569 ?dob.
   
   # get the label 
   # ?tournament sc:name ?tournamentName .
   # ?yearlyTournament sc:name ?yearlyTournamentName .
   # ?subTournament sc:name ?subTournamentName.
   # ?winner sc:name ?winnerName.
   # ?competitionClass sc:name ?competitionClassName.
   
   BIND(xsd:integer(SUBSTR(?yearlyTournamentName,0,4)) as ?year)
}
GROUP BY ?winner ?winnerName ?competitionClassName ?year
HAVING (count(*) >2)
ORDER BY DESC (?year)
LIMIT 50

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('winnerName', 'Novak Djokovic'), ('competitionClassName', "men's singles"), ('year', '2021'), ('tot', '3')]
# [('winnerName', 'Diede de Groot'), ('competitionClassName', "wheelchair tennis women's singles"), ('year', '2019'), ('tot', '3')]
# [('winnerName', 'Diede de Groot'), ('competitionClassName', "wheelchair tennis women's doubles"), ('year', '2019'), ('tot', '4')]
# [('winnerName', 'Diede de Groot'), ('competitionClassName', "wheelchair tennis women's doubles"), ('year', '2018'), ('tot', '3')]
# [('winnerName', 'Diede de Groot'), ('competitionClassName', "wheelchair tennis women's singles"), ('year', '2018'), ('tot', '3')]
# [('winnerName', 'Yui Kamiji'), ('competitionClassName', "wheelchair tennis women's singles"), ('year', '2017'), ('tot', '3')]
# [('winnerName', 'Martina Hingis'), ('competitionClassName', 'mixed doubles'), ('year', '2015'), ('tot', '3')]
# [('winnerName', 'Serena Williams'), ('competitionClassName', "women's singles"), ('year', '2015'), ('tot', '3')]
# [('winnerName', 'Novak Djokovic'), ('competitionClassName', "men's singles"), ('year', '2015'), ('tot', '3')]
# [('winnerName', 'Leander Paes'), ('competitionClassName', 'mixed doubles'), ('year', '2015'), ('tot', '3')]
# [('winnerName', 'Bob Bryan'), ('competitionClassName', "men's doubles"), ('year', '2013'), ('tot', '3')]
# [('winnerName', 'Venus Williams'), ('competitionClassName', "women's doubles"), ('year', '2009'), ('tot', '3')]
# [('winnerName', 'Serena Williams'), ('competitionClassName', "women's doubles"), ('year', '2009'), ('tot', '3')]
# [('winnerName', 'Virginia Ruano Pascual'), ('competitionClassName', "women's doubles"), ('year', '2004'), ('tot', '3')]
# [('winnerName', 'Roger Federer'), ('competitionClassName', "men's singles"), ('year', '2004'), ('tot', '3')]
# [('winnerName', 'Jacco Eltingh'), ('competitionClassName', "men's doubles"), ('year', '1998'), ('tot', '3')]
# [('winnerName', 'Martina Hingis'), ('competitionClassName', "women's doubles"), ('year', '1998'), ('tot', '3')]
# [('winnerName', 'Martina Hingis'), ('competitionClassName', "women's singles"), ('year', '1997'), ('tot', '3')]
# [('winnerName', 'Steffi Graf'), ('competitionClassName', "women's singles"), ('year', '1995'), ('tot', '3')]
# [('winnerName', 'Gigi Fernández'), ('competitionClassName', "women's doubles"), ('year', '1994'), ('tot', '3')]
# [('winnerName', 'Natasha Zvereva'), ('competitionClassName', "women's doubles"), ('year', '1994'), ('tot', '3')]
# [('winnerName', 'Gigi Fernández'), ('competitionClassName', "women's doubles"), ('year', '1993'), ('tot', '3')]
# [('winnerName', 'Steffi Graf'), ('competitionClassName', "women's singles"), ('year', '1993'), ('tot', '3')]
# [('winnerName', 'Gigi Fernández'), ('competitionClassName', "women's doubles"), ('year', '1992'), ('tot', '3')]
# [('winnerName', 'Natasha Zvereva'), ('competitionClassName', "women's doubles"), ('year', '1992'), ('tot', '3')]
# [('winnerName', 'Monica Seles'), ('competitionClassName', "women's singles"), ('year', '1992'), ('tot', '3')]
# [('winnerName', 'Jana Novotná'), ('competitionClassName', "women's doubles"), ('year', '1990'), ('tot', '3')]
# [('winnerName', 'Steffi Graf'), ('competitionClassName', "women's singles"), ('year', '1988'), ('tot', '4')]
# [('winnerName', 'Mats Wilander'), ('competitionClassName', "men's singles"), ('year', '1988'), ('tot', '3')]
# [('winnerName', 'Martina Navratilova'), ('competitionClassName', "women's doubles"), ('year', '1987'), ('tot', '3')]
# [('winnerName', 'Martina Navratilova'), ('competitionClassName', "women's doubles"), ('year', '1986'), ('tot', '3')]
# [('winnerName', 'Martina Navratilova'), ('competitionClassName', 'mixed doubles'), ('year', '1985'), ('tot', '3')]
# [('winnerName', 'Martina Navratilova'), ('competitionClassName', "women's doubles"), ('year', '1983'), ('tot', '3')]
# [('winnerName', 'Martina Navratilova'), ('competitionClassName', "women's singles"), ('year', '1983'), ('tot', '3')]
# [('winnerName', 'Martina Navratilova'), ('competitionClassName', "women's doubles"), ('year', '1982'), ('tot', '3')]
# [('winnerName', 'Bob Hewitt'), ('competitionClassName', 'mixed doubles'), ('year', '1979'), ('tot', '3')]
# [('winnerName', 'Rod Laver'), ('competitionClassName', "men's singles"), ('year', '1962'), ('tot', '3')]
# [('winnerName', 'Lew Hoad'), ('competitionClassName', "men's singles"), ('year', '1956'), ('tot', '3')]
# [('winnerName', 'Maureen Connolly'), ('competitionClassName', "women's singles"), ('year', '1953'), ('tot', '3')]
# 39

# %% [markdown]
# ##### Almost done, except some result on wikipedia for eg. all the following has won all 4 in the same year
# ```
#     for male: 1969 Rod Laver,1962 Rod Laver,1938 Don Budge
# ```
# ```
#     for female: 1953 Maureen Connolly,1970 Margaret Smith Court
# ```
#
# Data is missing

# %%
# write your queries
# Consider the country for sport property of the tennis player (NO Country of citizenship). 
# Return the countries with at least one player who won at least one edition of each Grand Slam (the result set must be a list of country IRI and label).

# [('p', 'http://www.wikidata.org/prop/direct/P1532'), ('name', 'country for sport')]

# P31 ('instance of')
# P527 ('has part')
# P1346 ('winner')

#[('obj', 'http://www.wikidata.org/entity/Q43605'), ('objName', 'French Open')]
#[('obj', 'http://www.wikidata.org/entity/Q123577'), ('objName', 'US Open')]
#[('obj', 'http://www.wikidata.org/entity/Q41520'), ('objName', 'Wimbledon Championships')]
#[('obj', 'http://www.wikidata.org/entity/Q60874'), ('objName', 'Australian Open')]

# 1) checking if in all seasons if someone has won all edition of each Grand Slam in the same category 
# 2) finding the winners of each GS tournament in each category
# 3) selecting only those who have 2 or more wins in the same category 

queryString = """

PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
SELECT DISTINCT ?winnerName ?competitionClassName ?year (COUNT(*) as ?tot)
WHERE {
   VALUES (?tournament){
       (wd:Q43605)
       (wd:Q123577)
       (wd:Q41520)
       (wd:Q60874)
   }
   # ?yearlyTournament wdt:P31 ?tournament.
   # ?yearlyTournament wdt:P527 ?subTournament.
   # ?subTournament wdt:P1346 ?winner;
                   wdt:P2094 ?competitionClass.
   
   # ?winner wdt:P569 ?dob.
   
   # get the label 
   # ?tournament sc:name ?tournamentName .
   # ?yearlyTournament sc:name ?yearlyTournamentName .
   # ?subTournament sc:name ?subTournamentName.
   # ?winner sc:name ?winnerName.
   # ?competitionClass sc:name ?competitionClassName.
   
   BIND(xsd:integer(SUBSTR(?yearlyTournamentName,0,4)) as ?year)
}
GROUP BY ?winner ?winnerName ?competitionClassName ?year
HAVING (count(*) >2)
ORDER BY DESC (?year)
LIMIT 100

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('winnerName', 'Novak Djokovic'), ('competitionClassName', "men's singles"), ('year', '2021'), ('tot', '3')]
# [('winnerName', 'Diede de Groot'), ('competitionClassName', "wheelchair tennis women's singles"), ('year', '2019'), ('tot', '3')]
# [('winnerName', 'Diede de Groot'), ('competitionClassName', "wheelchair tennis women's doubles"), ('year', '2019'), ('tot', '4')]
# [('winnerName', 'Diede de Groot'), ('competitionClassName', "wheelchair tennis women's doubles"), ('year', '2018'), ('tot', '3')]
# [('winnerName', 'Diede de Groot'), ('competitionClassName', "wheelchair tennis women's singles"), ('year', '2018'), ('tot', '3')]
# [('winnerName', 'Yui Kamiji'), ('competitionClassName', "wheelchair tennis women's singles"), ('year', '2017'), ('tot', '3')]
# [('winnerName', 'Martina Hingis'), ('competitionClassName', 'mixed doubles'), ('year', '2015'), ('tot', '3')]
# [('winnerName', 'Serena Williams'), ('competitionClassName', "women's singles"), ('year', '2015'), ('tot', '3')]
# [('winnerName', 'Novak Djokovic'), ('competitionClassName', "men's singles"), ('year', '2015'), ('tot', '3')]
# [('winnerName', 'Leander Paes'), ('competitionClassName', 'mixed doubles'), ('year', '2015'), ('tot', '3')]
# [('winnerName', 'Bob Bryan'), ('competitionClassName', "men's doubles"), ('year', '2013'), ('tot', '3')]
# [('winnerName', 'Venus Williams'), ('competitionClassName', "women's doubles"), ('year', '2009'), ('tot', '3')]
# [('winnerName', 'Serena Williams'), ('competitionClassName', "women's doubles"), ('year', '2009'), ('tot', '3')]
# [('winnerName', 'Virginia Ruano Pascual'), ('competitionClassName', "women's doubles"), ('year', '2004'), ('tot', '3')]
# [('winnerName', 'Roger Federer'), ('competitionClassName', "men's singles"), ('year', '2004'), ('tot', '3')]
# [('winnerName', 'Jacco Eltingh'), ('competitionClassName', "men's doubles"), ('year', '1998'), ('tot', '3')]
# [('winnerName', 'Martina Hingis'), ('competitionClassName', "women's doubles"), ('year', '1998'), ('tot', '3')]
# [('winnerName', 'Martina Hingis'), ('competitionClassName', "women's singles"), ('year', '1997'), ('tot', '3')]
# [('winnerName', 'Steffi Graf'), ('competitionClassName', "women's singles"), ('year', '1995'), ('tot', '3')]
# [('winnerName', 'Gigi Fernández'), ('competitionClassName', "women's doubles"), ('year', '1994'), ('tot', '3')]
# [('winnerName', 'Natasha Zvereva'), ('competitionClassName', "women's doubles"), ('year', '1994'), ('tot', '3')]
# [('winnerName', 'Gigi Fernández'), ('competitionClassName', "women's doubles"), ('year', '1993'), ('tot', '3')]
# [('winnerName', 'Steffi Graf'), ('competitionClassName', "women's singles"), ('year', '1993'), ('tot', '3')]
# [('winnerName', 'Gigi Fernández'), ('competitionClassName', "women's doubles"), ('year', '1992'), ('tot', '3')]
# [('winnerName', 'Natasha Zvereva'), ('competitionClassName', "women's doubles"), ('year', '1992'), ('tot', '3')]
# [('winnerName', 'Monica Seles'), ('competitionClassName', "women's singles"), ('year', '1992'), ('tot', '3')]
# [('winnerName', 'Jana Novotná'), ('competitionClassName', "women's doubles"), ('year', '1990'), ('tot', '3')]
# [('winnerName', 'Steffi Graf'), ('competitionClassName', "women's singles"), ('year', '1988'), ('tot', '4')]
# [('winnerName', 'Mats Wilander'), ('competitionClassName', "men's singles"), ('year', '1988'), ('tot', '3')]
# [('winnerName', 'Martina Navratilova'), ('competitionClassName', "women's doubles"), ('year', '1987'), ('tot', '3')]
# [('winnerName', 'Martina Navratilova'), ('competitionClassName', "women's doubles"), ('year', '1986'), ('tot', '3')]
# [('winnerName', 'Martina Navratilova'), ('competitionClassName', 'mixed doubles'), ('year', '1985'), ('tot', '3')]
# [('winnerName', 'Martina Navratilova'), ('competitionClassName', "women's doubles"), ('year', '1983'), ('tot', '3')]
# [('winnerName', 'Martina Navratilova'), ('competitionClassName', "women's singles"), ('year', '1983'), ('tot', '3')]
# [('winnerName', 'Martina Navratilova'), ('competitionClassName', "women's doubles"), ('year', '1982'), ('tot', '3')]
# [('winnerName', 'Bob Hewitt'), ('competitionClassName', 'mixed doubles'), ('year', '1979'), ('tot', '3')]
# [('winnerName', 'Rod Laver'), ('competitionClassName', "men's singles"), ('year', '1962'), ('tot', '3')]
# [('winnerName', 'Lew Hoad'), ('competitionClassName', "men's singles"), ('year', '1956'), ('tot', '3')]
# [('winnerName', 'Maureen Connolly'), ('competitionClassName', "women's singles"), ('year', '1953'), ('tot', '3')]
# 39

# %%
# write your queries
# Consider the country for sport property of the tennis player (NO Country of citizenship). 
# Return the countries with at least one player who won at least one edition of each Grand Slam (the result set must be a list of country IRI and label).

# [('p', 'http://www.wikidata.org/prop/direct/P1532'), ('name', 'country for sport')]

# P31 ('instance of')
# P527 ('has part')
# P1346 ('winner')

#[('obj', 'http://www.wikidata.org/entity/Q43605'), ('objName', 'French Open')]
#[('obj', 'http://www.wikidata.org/entity/Q123577'), ('objName', 'US Open')]
#[('obj', 'http://www.wikidata.org/entity/Q41520'), ('objName', 'Wimbledon Championships')]
#[('obj', 'http://www.wikidata.org/entity/Q60874'), ('objName', 'Australian Open')]

# 1) checking if in all seasons if someone has won all edition of each Grand Slam in the same category 
# 2) finding the winners of each GS tournament in each category
# 3) selecting only those who have 4 or more wins in the same category

queryString = """

PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
SELECT DISTINCT ?winnerName ?competitionClassName ?year (COUNT(*) as ?tot)
WHERE {
   VALUES (?tournament){
       (wd:Q43605)
       (wd:Q123577)
       (wd:Q41520)
       (wd:Q60874)
   }
   # ?yearlyTournament wdt:P31 ?tournament.
   # ?yearlyTournament wdt:P527 ?subTournament.
   # ?subTournament wdt:P1346 ?winner;
                   wdt:P2094 ?competitionClass.
   
   # ?winner wdt:P569 ?dob.
   
   # get the label 
   # ?tournament sc:name ?tournamentName .
   # ?yearlyTournament sc:name ?yearlyTournamentName .
   # ?subTournament sc:name ?subTournamentName.
   # ?winner sc:name ?winnerName.
   # ?competitionClass sc:name ?competitionClassName.
   
   BIND(xsd:integer(SUBSTR(?yearlyTournamentName,0,4)) as ?year)
}
GROUP BY ?winner ?winnerName ?competitionClassName ?year
HAVING (count(*) >=4)
ORDER BY DESC (?year)
LIMIT 100

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('winnerName', 'Diede de Groot'), ('competitionClassName', "wheelchair tennis women's doubles"), ('year', '2019'), ('tot', '4')]
# [('winnerName', 'Steffi Graf'), ('competitionClassName', "women's singles"), ('year', '1988'), ('tot', '4')]
# 2

# %%
# write your queries
# Consider the country for sport property of the tennis player (NO Country of citizenship). 
# Return the countries with at least one player who won at least one edition of each Grand Slam (the result set must be a list of country IRI and label).

# [('p', 'http://www.wikidata.org/prop/direct/P1532'), ('name', 'country for sport')]

# P31 ('instance of')
# P527 ('has part')
# P1346 ('winner')

#[('obj', 'http://www.wikidata.org/entity/Q43605'), ('objName', 'French Open')]
#[('obj', 'http://www.wikidata.org/entity/Q123577'), ('objName', 'US Open')]
#[('obj', 'http://www.wikidata.org/entity/Q41520'), ('objName', 'Wimbledon Championships')]
#[('obj', 'http://www.wikidata.org/entity/Q60874'), ('objName', 'Australian Open')]

# 1) checking if in all seasons if someone has won all edition of each Grand Slam in the same category 
# 2) finding the winners of each GS tournament in each category
# 3) selecting only those who have 4 or more wins in the same category
# 4) getting the country for sport of the players
queryString = """

PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
SELECT DISTINCT ?winnerName ?countryForSport ?competitionClassName ?year (COUNT(*) as ?tot)
WHERE {
   VALUES (?tournament){
       (wd:Q43605)
       (wd:Q123577)
       (wd:Q41520)
       (wd:Q60874)
   }
   # ?yearlyTournament wdt:P31 ?tournament.
   # ?yearlyTournament wdt:P527 ?subTournament.
   # ?subTournament wdt:P1346 ?winner;
                   wdt:P2094 ?competitionClass.
   
   # ?winner wdt:P1532 ?countryForSport.
   
   # get the label 
   # ?tournament sc:name ?tournamentName .
   # ?yearlyTournament sc:name ?yearlyTournamentName .
   # ?subTournament sc:name ?subTournamentName.
   # ?winner sc:name ?winnerName.
   # ?competitionClass sc:name ?competitionClassName.
   
   BIND(xsd:integer(SUBSTR(?yearlyTournamentName,0,4)) as ?year)
}
GROUP BY ?winner ?winnerName ?countryForSport ?competitionClassName ?year
HAVING (count(*) >=4)
ORDER BY DESC (?year)
LIMIT 100

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('winnerName', 'Steffi Graf'), ('countryForSport', 'http://www.wikidata.org/entity/Q183'), ('competitionClassName', "women's singles"), ('year', '1988'), ('tot', '4')]
# 1

# %% [markdown]
# ##### Attention One record is withoud P1532 (coutry for sport) relationship ! SEE ABOVE

# %% [markdown]
# ##### Now trying to finding sol for data missing for
# ```
#     for male: 1969 Rod Laver,1962 Rod Laver,1938 Don Budge
# ```
# ```
#     for female: 1953 Maureen Connolly,1970 Margaret Smith Court
# ```

# %%
# write your queries
# Consider the country for sport property of the tennis player (NO Country of citizenship). 
# Return the countries with at least one player who won at least one edition of each Grand Slam (the result set must be a list of country IRI and label).

# [('p', 'http://www.wikidata.org/prop/direct/P1532'), ('name', 'country for sport')]

# P31 ('instance of')
# P527 ('has part')
# P1346 ('winner')

#[('obj', 'http://www.wikidata.org/entity/Q43605'), ('objName', 'French Open')]
#[('obj', 'http://www.wikidata.org/entity/Q123577'), ('objName', 'US Open')]
#[('obj', 'http://www.wikidata.org/entity/Q41520'), ('objName', 'Wimbledon Championships')]
#[('obj', 'http://www.wikidata.org/entity/Q60874'), ('objName', 'Australian Open')]

# getting all games in 1969

queryString = """

PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
SELECT DISTINCT ?subTournamentName ?winnerName ?year ?competitionClassName ?subTournament ?yearlyTournament
WHERE {
   VALUES (?tournament){
       (wd:Q43605)
       (wd:Q123577)
       (wd:Q41520)
       (wd:Q60874)
   }
   # ?yearlyTournament wdt:P31 ?tournament.
   # ?yearlyTournament wdt:P527 ?subTournament.
   # ?subTournament wdt:P1346 ?winner;
                   wdt:P2094 ?competitionClass.
      
   # get the label 
   # ?tournament sc:name ?tournamentName .
   # ?yearlyTournament sc:name ?yearlyTournamentName .
   # ?subTournament sc:name ?subTournamentName.
   # ?winner sc:name ?winnerName.
   # ?competitionClass sc:name ?competitionClassName.
   
   BIND(xsd:integer(SUBSTR(?yearlyTournamentName,0,4)) as ?year)
   FILTER(?year = "1969"^^xsd:integer)
}
#GROUP BY ?winner ?winnerName ?competitionClassName ?year
#HAVING (count(*) >=4)
#ORDER BY DESC (?year)
LIMIT 100

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('subTournamentName', '1969 French Open – Mixed Doubles'), ('winnerName', 'Marty Riessen'), ('year', '1969'), ('competitionClassName', 'mixed doubles'), ('subTournament', 'http://www.wikidata.org/entity/Q3037679'), ('yearlyTournament', 'http://www.wikidata.org/entity/Q202226')]
# [('subTournamentName', "1969 French Open – Men's Doubles"), ('winnerName', 'John Newcombe'), ('year', '1969'), ('competitionClassName', "men's doubles"), ('subTournament', 'http://www.wikidata.org/entity/Q12412317'), ('yearlyTournament', 'http://www.wikidata.org/entity/Q202226')]
# [('subTournamentName', "1969 French Open – Women's Doubles"), ('winnerName', 'Françoise Dürr'), ('year', '1969'), ('competitionClassName', "women's doubles"), ('subTournament', 'http://www.wikidata.org/entity/Q1455320'), ('yearlyTournament', 'http://www.wikidata.org/entity/Q202226')]
# [('subTournamentName', "1969 French Open – Women's Singles"), ('winnerName', 'Margaret Court'), ('year', '1969'), ('competitionClassName', "women's singles"), ('subTournament', 'http://www.wikidata.org/entity/Q594977'), ('yearlyTournament', 'http://www.wikidata.org/entity/Q202226')]
# [('subTournamentName', "1969 French Open – Men's Singles"), ('winnerName', 'Rod Laver'), ('year', '1969'), ('competitionClassName', "men's singles"), ('subTournament', 'http://www.wikidata.org/entity/Q2715007'), ('yearlyTournament', 'http://www.wikidata.org/entity/Q202226')]
# [('subTournamentName', '1969 Australian Open – Mixed Doubles'), ('winnerName', 'Margaret Court'), ('year', '1969'), ('competitionClassName', 'mixed doubles'), ('subTournament', 'http://www.wikidata.org/entity/Q781620'), ('yearlyTournament', 'http://www.wikidata.org/entity/Q602116')]
# [('subTournamentName', "1969 Australian Open – Women's Singles"), ('winnerName', 'Margaret Court'), ('year', '1969'), ('competitionClassName', "women's singles"), ('subTournament', 'http://www.wikidata.org/entity/Q781629'), ('yearlyTournament', 'http://www.wikidata.org/entity/Q602116')]
# [('subTournamentName', "1969 Australian Open – Women's Doubles"), ('winnerName', 'Margaret Court'), ('year', '1969'), ('competitionClassName', "women's doubles"), ('subTournament', 'http://www.wikidata.org/entity/Q781612'), ('yearlyTournament', 'http://www.wikidata.org/entity/Q602116')]
# [('subTournamentName', "1969 Australian Open – Men's Doubles"), ('winnerName', 'Rod Laver'), ('year', '1969'), ('competitionClassName', "men's doubles"), ('subTournament', 'http://www.wikidata.org/entity/Q2364152'), ('yearlyTournament', 'http://www.wikidata.org/entity/Q602116')]
# [('subTournamentName', "1969 Australian Open – Men's Singles"), ('winnerName', 'Rod Laver'), ('year', '1969'), ('competitionClassName', "men's singles"), ('subTournament', 'http://www.wikidata.org/entity/Q764694'), ('yearlyTournament', 'http://www.wikidata.org/entity/Q602116')]
# [('subTournamentName', '1969 Australian Open – Mixed Doubles'), ('winnerName', 'Ann Haydon-Jones'), ('year', '1969'), ('competitionClassName', 'mixed doubles'), ('subTournament', 'http://www.wikidata.org/entity/Q781620'), ('yearlyTournament', 'http://www.wikidata.org/entity/Q602116')]
# 11

# %%
# write your queries
# Consider the country for sport property of the tennis player (NO Country of citizenship). 
# Return the countries with at least one player who won at least one edition of each Grand Slam (the result set must be a list of country IRI and label).

# [('p', 'http://www.wikidata.org/prop/direct/P1532'), ('name', 'country for sport')]

# P31 ('instance of')
# P527 ('has part')
# P1346 ('winner')

#[('obj', 'http://www.wikidata.org/entity/Q43605'), ('objName', 'French Open')]
#[('obj', 'http://www.wikidata.org/entity/Q123577'), ('objName', 'US Open')]
#[('obj', 'http://www.wikidata.org/entity/Q41520'), ('objName', 'Wimbledon Championships')]
#[('obj', 'http://www.wikidata.org/entity/Q60874'), ('objName', 'Australian Open')]

# prob: missing Men's Single in US open and Wimbledon Chapionshiops in 1969

queryString = """

PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
SELECT DISTINCT ?subTournamentName ?winnerName ?year ?subTournament ?yearlyTournament
WHERE {
   VALUES (?tournament){
       (wd:Q43605)
       (wd:Q123577)
       (wd:Q41520)
       (wd:Q60874)
   }
   # ?yearlyTournament wdt:P31 ?tournament.
   # ?yearlyTournament wdt:P527 ?subTournament.
   # ?subTournament wdt:P1346 ?winner.
      
   # get the label 
   # ?tournament sc:name ?tournamentName .
   # ?yearlyTournament sc:name ?yearlyTournamentName .
   # ?subTournament sc:name ?subTournamentName.
   # ?winner sc:name ?winnerName.
   
   BIND(xsd:integer(SUBSTR(?yearlyTournamentName,0,4)) as ?year)
   FILTER(?year = "1969"^^xsd:integer)
}
#GROUP BY ?winner ?winnerName ?competitionClassName ?year
#HAVING (count(*) >=4)
#ORDER BY DESC (?year)
LIMIT 100

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('subTournamentName', '1969 French Open – Mixed Doubles'), ('winnerName', 'Marty Riessen'), ('year', '1969'), ('subTournament', 'http://www.wikidata.org/entity/Q3037679'), ('yearlyTournament', 'http://www.wikidata.org/entity/Q202226')]
# [('subTournamentName', "1969 French Open – Men's Doubles"), ('winnerName', 'John Newcombe'), ('year', '1969'), ('subTournament', 'http://www.wikidata.org/entity/Q12412317'), ('yearlyTournament', 'http://www.wikidata.org/entity/Q202226')]
# [('subTournamentName', "1969 French Open – Women's Doubles"), ('winnerName', 'Françoise Dürr'), ('year', '1969'), ('subTournament', 'http://www.wikidata.org/entity/Q1455320'), ('yearlyTournament', 'http://www.wikidata.org/entity/Q202226')]
# [('subTournamentName', "1969 French Open – Women's Singles"), ('winnerName', 'Margaret Court'), ('year', '1969'), ('subTournament', 'http://www.wikidata.org/entity/Q594977'), ('yearlyTournament', 'http://www.wikidata.org/entity/Q202226')]
# [('subTournamentName', "1969 French Open – Men's Singles"), ('winnerName', 'Rod Laver'), ('year', '1969'), ('subTournament', 'http://www.wikidata.org/entity/Q2715007'), ('yearlyTournament', 'http://www.wikidata.org/entity/Q202226')]
# [('subTournamentName', '1969 Australian Open – Mixed Doubles'), ('winnerName', 'Margaret Court'), ('year', '1969'), ('subTournament', 'http://www.wikidata.org/entity/Q781620'), ('yearlyTournament', 'http://www.wikidata.org/entity/Q602116')]
# [('subTournamentName', "1969 Australian Open – Women's Singles"), ('winnerName', 'Margaret Court'), ('year', '1969'), ('subTournament', 'http://www.wikidata.org/entity/Q781629'), ('yearlyTournament', 'http://www.wikidata.org/entity/Q602116')]
# [('subTournamentName', "1969 Australian Open – Women's Doubles"), ('winnerName', 'Margaret Court'), ('year', '1969'), ('subTournament', 'http://www.wikidata.org/entity/Q781612'), ('yearlyTournament', 'http://www.wikidata.org/entity/Q602116')]
# [('subTournamentName', "1969 Australian Open – Men's Doubles"), ('winnerName', 'Rod Laver'), ('year', '1969'), ('subTournament', 'http://www.wikidata.org/entity/Q2364152'), ('yearlyTournament', 'http://www.wikidata.org/entity/Q602116')]
# [('subTournamentName', "1969 Australian Open – Men's Singles"), ('winnerName', 'Rod Laver'), ('year', '1969'), ('subTournament', 'http://www.wikidata.org/entity/Q764694'), ('yearlyTournament', 'http://www.wikidata.org/entity/Q602116')]
# [('subTournamentName', '1969 Australian Open – Mixed Doubles'), ('winnerName', 'Ann Haydon-Jones'), ('year', '1969'), ('subTournament', 'http://www.wikidata.org/entity/Q781620'), ('yearlyTournament', 'http://www.wikidata.org/entity/Q602116')]
# 11

# %%
# write your queries
# Consider the country for sport property of the tennis player (NO Country of citizenship). 
# Return the countries with at least one player who won at least one edition of each Grand Slam (the result set must be a list of country IRI and label).

# [('p', 'http://www.wikidata.org/prop/direct/P1532'), ('name', 'country for sport')]

# P31 ('instance of')
# P527 ('has part')
# P1346 ('winner')

#[('obj', 'http://www.wikidata.org/entity/Q43605'), ('objName', 'French Open')]
#[('obj', 'http://www.wikidata.org/entity/Q123577'), ('objName', 'US Open')]
#[('obj', 'http://www.wikidata.org/entity/Q41520'), ('objName', 'Wimbledon Championships')]
#[('obj', 'http://www.wikidata.org/entity/Q60874'), ('objName', 'Australian Open')]

# checking if removing filter solves the porblem

queryString = """

PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
SELECT DISTINCT ?subTournamentName ?winnerName ?competitionClassName ?yearlyTournamentName
WHERE {
   VALUES (?tournament){
       (wd:Q43605)
       (wd:Q123577)
       (wd:Q41520)
       (wd:Q60874)
   }
   # ?yearlyTournament wdt:P31 ?tournament.
   # ?yearlyTournament wdt:P527 ?subTournament.
   # ?subTournament wdt:P1346 ?winner;
                   wdt:P2094 ?competitionClass.
      
   # get the label 
   # ?tournament sc:name ?tournamentName .
   # ?yearlyTournament sc:name ?yearlyTournamentName .
   # ?subTournament sc:name ?subTournamentName.
   # ?winner sc:name ?winnerName.
   # ?competitionClass sc:name ?competitionClassName.
}
ORDER BY ASC (?yearlyTournamentName)
LIMIT 200

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('subTournamentName', '1877 Wimbledon Championship – singles'), ('winnerName', 'Spencer Gore'), ('competitionClassName', "men's singles"), ('yearlyTournamentName', '1877 Wimbledon Championship')]
# [('subTournamentName', '1878 Wimbledon Championship – singles'), ('winnerName', 'Frank Hadow'), ('competitionClassName', "men's singles"), ('yearlyTournamentName', '1878 Wimbledon Championships')]
# [('subTournamentName', '1879 Wimbledon Championship – singles'), ('winnerName', 'John Hartley'), ('competitionClassName', "men's singles"), ('yearlyTournamentName', '1879 Wimbledon Championship')]
# [('subTournamentName', '1880 Wimbledon Championship – singles'), ('winnerName', 'John Hartley'), ('competitionClassName', "men's singles"), ('yearlyTournamentName', '1880 Wimbledon Championship')]
# [('subTournamentName', '1881 Wimbledon Championship – singles'), ('winnerName', 'William Renshaw'), ('competitionClassName', "men's singles"), ('yearlyTournamentName', '1881 Wimbledon Championship')]
# [('subTournamentName', '1882 Wimbledon Championship – singles'), ('winnerName', 'William Renshaw'), ('competitionClassName', "men's singles"), ('yearlyTournamentName', '1882 Wimbledon Championship')]
# [('subTournamentName', '1883 Wimbledon Championship – singles'), ('winnerName', 'William Renshaw'), ('competitionClassName', "men's singles"), ('yearlyTournamentName', '1883 Wimbledon Championship')]
# [('subTournamentName', "1884 Wimbledon Championships – Gentlemen's Singles"), ('winnerName', 'William Renshaw'), ('competitionClassName', "men's singles"), ('yearlyTournamentName', '1884 Wimbledon Championships')]
# [('subTournamentName', "1884 Wimbledon Championships – Ladies' Singles"), ('winnerName', 'Maud Watson'), ('competitionClassName', "women's singles"), ('yearlyTournamentName', '1884 Wimbledon Championships')]
# [('subTournamentName', "1885 Wimbledon Championships – Gentlemen's Singles"), ('winnerName', 'William Renshaw'), ('competitionClassName', "men's singles"), ('yearlyTournamentName', '1885 Wimbledon Championships')]
# [('subTournamentName', "1885 Wimbledon Championships – Ladies' Singles"), ('winnerName', 'Maud Watson'), ('competitionClassName', "women's singles"), ('yearlyTournamentName', '1885 Wimbledon Championships')]
# [('subTournamentName', "1886 Wimbledon Championships – Gentlemen's Singles"), ('winnerName', 'William Renshaw'), ('competitionClassName', "men's singles"), ('yearlyTournamentName', '1886 Wimbledon Championships')]
# [('subTournamentName', "1886 Wimbledon Championships – Ladies' Singles"), ('winnerName', 'Blanche Bingley'), ('competitionClassName', "women's singles"), ('yearlyTournamentName', '1886 Wimbledon Championships')]
# [('subTournamentName', "1886 Wimbledon Championships – Gentlemen's Doubles"), ('winnerName', 'Ernest Renshaw'), ('competitionClassName', "men's doubles"), ('yearlyTournamentName', '1886 Wimbledon Championships')]
# [('subTournamentName', "1887 U.S. National Championships – Men's Singles"), ('winnerName', 'Richard Sears'), ('competitionClassName', "men's singles"), ('yearlyTournamentName', '1887 U.S. National Championships')]
# [('subTournamentName', "1887 U.S. National Championships – Men's Doubles"), ('winnerName', 'Richard Sears'), ('competitionClassName', "men's doubles"), ('yearlyTournamentName', '1887 U.S. National Championships')]
# [('subTournamentName', "1887 U.S. National Championships – Women's Singles"), ('winnerName', 'Ellen Hansell'), ('competitionClassName', "women's singles"), ('yearlyTournamentName', '1887 U.S. National Championships')]
# [('subTournamentName', "1888 U.S. National Championships – Men's Singles"), ('winnerName', 'Henry Warner Slocum, Jr.'), ('competitionClassName', "men's singles"), ('yearlyTournamentName', '1888 U.S. National Championships')]
# [('subTournamentName', "1888 U.S. National Championships – Men's Doubles"), ('winnerName', 'Valentine Hall'), ('competitionClassName', "men's doubles"), ('yearlyTournamentName', '1888 U.S. National Championships')]
# [('subTournamentName', "1888 U.S. National Championships – Women's Singles"), ('winnerName', 'Bertha Townsend'), ('competitionClassName', "women's singles"), ('yearlyTournamentName', '1888 U.S. National Championships')]
# [('subTournamentName', "1889 U.S. National Championships – Women's Singles"), ('winnerName', 'Bertha Townsend'), ('competitionClassName', "women's singles"), ('yearlyTournamentName', '1889 U.S. National Championships')]
# [('subTournamentName', "1889 U.S. National Championships – Men's Singles"), ('winnerName', 'Henry Warner Slocum, Jr.'), ('competitionClassName', "men's singles"), ('yearlyTournamentName', '1889 U.S. National Championships')]
# [('subTournamentName', "1889 U.S. National Championships – Men's Doubles"), ('winnerName', 'Henry Warner Slocum, Jr.'), ('competitionClassName', "men's doubles"), ('yearlyTournamentName', '1889 U.S. National Championships')]
# [('subTournamentName', "1890 U.S. National Championships – Men's Singles"), ('winnerName', 'Oliver Campbell'), ('competitionClassName', "men's singles"), ('yearlyTournamentName', '1890 U.S. National Championships')]
# [('subTournamentName', "1890 U.S. National Championships – Women's Singles"), ('winnerName', 'Ellen Roosevelt'), ('competitionClassName', "women's singles"), ('yearlyTournamentName', '1890 U.S. National Championships')]
# [('subTournamentName', "1891 U.S. National Championships – Men's Singles"), ('winnerName', 'Oliver Campbell'), ('competitionClassName', "men's singles"), ('yearlyTournamentName', '1891 U.S. National Championships')]
# [('subTournamentName', "1891 U.S. National Championships – Women's Singles"), ('winnerName', 'Mabel Cahill'), ('competitionClassName', "women's singles"), ('yearlyTournamentName', '1891 U.S. National Championships')]
# [('subTournamentName', "1892 U.S. National Championships – Men's Singles"), ('winnerName', 'Oliver Campbell'), ('competitionClassName', "men's singles"), ('yearlyTournamentName', '1892 U.S. National Championships')]
# [('subTournamentName', "1892 U.S. National Championships – Women's Singles"), ('winnerName', 'Mabel Cahill'), ('competitionClassName', "women's singles"), ('yearlyTournamentName', '1892 U.S. National Championships')]
# [('subTournamentName', "1893 U.S. National Championships – Women's Singles"), ('winnerName', 'Aline Terry'), ('competitionClassName', "women's singles"), ('yearlyTournamentName', '1893 U.S. National Championships')]
# [('subTournamentName', "1893 U.S. National Championships – Men's Singles"), ('winnerName', 'Robert Wrenn'), ('competitionClassName', "men's singles"), ('yearlyTournamentName', '1893 U.S. National Championships')]
# [('subTournamentName', "1894 U.S. National Championships – Women's Singles"), ('winnerName', 'Helen Hellwig'), ('competitionClassName', "women's singles"), ('yearlyTournamentName', '1894 U.S. National Championships')]
# [('subTournamentName', "1894 U.S. National Championships – Men's Singles"), ('winnerName', 'Robert Wrenn'), ('competitionClassName', "men's singles"), ('yearlyTournamentName', '1894 U.S. National Championships')]
# [('subTournamentName', "1895 U.S. National Championships – Women's Singles"), ('winnerName', 'Juliette Atkinson'), ('competitionClassName', "women's singles"), ('yearlyTournamentName', '1895 U.S. National Championships')]
# [('subTournamentName', "1895 U.S. National Championships – Men's Singles"), ('winnerName', 'Frederick Hovey'), ('competitionClassName', "men's singles"), ('yearlyTournamentName', '1895 U.S. National Championships')]
# [('subTournamentName', "1896 U.S. National Championships – Women's Singles"), ('winnerName', 'Elisabeth Moore'), ('competitionClassName', "women's singles"), ('yearlyTournamentName', '1896 U.S. National Championships')]
# [('subTournamentName', "1896 U.S. National Championships – Men's Singles"), ('winnerName', 'Robert Wrenn'), ('competitionClassName', "men's singles"), ('yearlyTournamentName', '1896 U.S. National Championships')]
# [('subTournamentName', '1905 Australasian Championships – doubles'), ('winnerName', 'Randolph Lycett'), ('competitionClassName', "men's doubles"), ('yearlyTournamentName', '1905 Australasian Championships')]
# [('subTournamentName', '1905 Australasian Championships – singles'), ('winnerName', 'Rodney Heath'), ('competitionClassName', "men's singles"), ('yearlyTournamentName', '1905 Australasian Championships')]
# [('subTournamentName', '1906 Australasian Championships – singles'), ('winnerName', 'Anthony Wilding'), ('competitionClassName', "men's singles"), ('yearlyTournamentName', '1906 Australasian Championships')]
# [('subTournamentName', '1906 Australasian Championships – doubles'), ('winnerName', 'Rodney Heath'), ('competitionClassName', "men's doubles"), ('yearlyTournamentName', '1906 Australasian Championships')]
# [('subTournamentName', '1907 Australasian Championships – singles'), ('winnerName', 'Horace Rice'), ('competitionClassName', "men's singles"), ('yearlyTournamentName', '1907 Australasian Championships')]
# [('subTournamentName', '1907 Australasian Championships – doubles'), ('winnerName', 'Bill Gregg'), ('competitionClassName', "men's doubles"), ('yearlyTournamentName', '1907 Australasian Championships')]
# [('subTournamentName', '1908 Australasian Championships – doubles'), ('winnerName', 'Fred Alexander'), ('competitionClassName', "men's doubles"), ('yearlyTournamentName', '1908 Australasian Championships')]
# [('subTournamentName', '1908 Australasian Championships – singles'), ('winnerName', 'Fred Alexander'), ('competitionClassName', "men's singles"), ('yearlyTournamentName', '1908 Australasian Championships')]
# [('subTournamentName', '1909 Australasian Championships – doubles'), ('winnerName', 'J.Keane'), ('competitionClassName', "men's doubles"), ('yearlyTournamentName', '1909 Australasian Championships')]
# [('subTournamentName', '1909 Australasian Championships – singles'), ('winnerName', 'Anthony Wilding'), ('competitionClassName', "men's singles"), ('yearlyTournamentName', '1909 Australasian Championships')]
# [('subTournamentName', '1910 Australasian Championships – doubles'), ('winnerName', 'Ashley Campbell'), ('competitionClassName', "men's doubles"), ('yearlyTournamentName', '1910 Australasian Championships')]
# [('subTournamentName', '1910 Australasian Championships – singles'), ('winnerName', 'Rodney Heath'), ('competitionClassName', "men's singles"), ('yearlyTournamentName', '1910 Australasian Championships')]
# [('subTournamentName', "1910 Wimbledon Championships – Men's Singles"), ('winnerName', 'Anthony Wilding'), ('competitionClassName', "men's singles"), ('yearlyTournamentName', '1910 Wimbledon Championships')]
# [('subTournamentName', "1910 Wimbledon Championships – Women's Singles"), ('winnerName', 'Dorothea Douglass'), ('competitionClassName', "women's singles"), ('yearlyTournamentName', '1910 Wimbledon Championships')]
# [('subTournamentName', "1910 Wimbledon Championships – Men's Doubles"), ('winnerName', 'Major Ritchie'), ('competitionClassName', "men's doubles"), ('yearlyTournamentName', '1910 Wimbledon Championships')]
# [('subTournamentName', '1911 Australasian Championships – doubles'), ('winnerName', 'Rodney Heath'), ('competitionClassName', "men's doubles"), ('yearlyTournamentName', '1911 Australasian Championships')]
# [('subTournamentName', '1911 Australasian Championships – singles'), ('winnerName', 'Norman Brookes'), ('competitionClassName', "men's singles"), ('yearlyTournamentName', '1911 Australasian Championships')]
# [('subTournamentName', '1912 Australasian Championships – singles'), ('winnerName', 'James Cecil Parke'), ('competitionClassName', "men's singles"), ('yearlyTournamentName', '1912 Australasian Championships')]
# [('subTournamentName', '1912 Australasian Championships – doubles'), ('winnerName', 'James Cecil Parke'), ('competitionClassName', "men's doubles"), ('yearlyTournamentName', '1912 Australasian Championships')]
# [('subTournamentName', '1913 Australasian Championships – doubles'), ('winnerName', 'Alf Hedeman'), ('competitionClassName', "men's doubles"), ('yearlyTournamentName', '1913 Australasian Championships')]
# [('subTournamentName', '1913 Australasian Championships – singles'), ('winnerName', 'Ernie Parker'), ('competitionClassName', "men's singles"), ('yearlyTournamentName', '1913 Australasian Championships')]
# [('subTournamentName', '1914 Australasian Championships – doubles'), ('winnerName', 'Ashley Campbell'), ('competitionClassName', "men's doubles"), ('yearlyTournamentName', '1914 Australasian Championships')]
# [('subTournamentName', '1914 Australasian Championships – singles'), ('winnerName', "Arthur O'Hara Wood"), ('competitionClassName', "men's singles"), ('yearlyTournamentName', '1914 Australasian Championships')]
# [('subTournamentName', '1915 Australasian Championships – singles'), ('winnerName', 'Gordon Lowe'), ('competitionClassName', "men's singles"), ('yearlyTournamentName', '1915 Australasian Championships')]
# [('subTournamentName', '1915 Australasian Championships – doubles'), ('winnerName', 'Horace Rice'), ('competitionClassName', "men's doubles"), ('yearlyTournamentName', '1915 Australasian Championships')]
# [('subTournamentName', "1922 Australasian Championships – Women's Doubles"), ('winnerName', 'Esna Boyd'), ('competitionClassName', "women's doubles"), ('yearlyTournamentName', '1922 Australasian Championships')]
# [('subTournamentName', "1922 Australasian Championships – Women's Singles"), ('winnerName', 'Margaret Molesworth'), ('competitionClassName', "women's singles"), ('yearlyTournamentName', '1922 Australasian Championships')]
# [('subTournamentName', '1922 Australasian Championships – Mixed Doubles'), ('winnerName', 'Esna Boyd'), ('competitionClassName', 'mixed doubles'), ('yearlyTournamentName', '1922 Australasian Championships')]
# [('subTournamentName', "1922 Australasian Championships – Men's Singles"), ('winnerName', 'James Anderson'), ('competitionClassName', "men's singles"), ('yearlyTournamentName', '1922 Australasian Championships')]
# [('subTournamentName', "1923 Australasian Championships – Men's Singles"), ('winnerName', "Pat O'Hara Wood"), ('competitionClassName', "men's singles"), ('yearlyTournamentName', '1923 Australasian Championships')]
# [('subTournamentName', '1923 Australasian Championships – Mixed Doubles'), ('winnerName', 'Sylvia Lance Harper'), ('competitionClassName', 'mixed doubles'), ('yearlyTournamentName', '1923 Australasian Championships')]
# [('subTournamentName', "1923 Australasian Championships – Women's Doubles"), ('winnerName', 'Esna Boyd'), ('competitionClassName', "women's doubles"), ('yearlyTournamentName', '1923 Australasian Championships')]
# [('subTournamentName', "1923 Australasian Championships – Women's Doubles"), ('winnerName', 'Sylvia Lance Harper'), ('competitionClassName', "women's doubles"), ('yearlyTournamentName', '1923 Australasian Championships')]
# [('subTournamentName', "1923 Australasian Championships – Women's Singles"), ('winnerName', 'Margaret Molesworth'), ('competitionClassName', "women's singles"), ('yearlyTournamentName', '1923 Australasian Championships')]
# [('subTournamentName', "1923 U.S. National Championships – Women's Singles"), ('winnerName', 'Helen Wills'), ('competitionClassName', "women's singles"), ('yearlyTournamentName', '1923 U.S. National Championships')]
# [('subTournamentName', "1923 U.S. National Championships – Men's Singles"), ('winnerName', 'Bill Tilden'), ('competitionClassName', "men's singles"), ('yearlyTournamentName', '1923 U.S. National Championships')]
# [('subTournamentName', "1924 Australasian Championships – Women's Singles"), ('winnerName', 'Sylvia Lance Harper'), ('competitionClassName', "women's singles"), ('yearlyTournamentName', '1924 Australasian Championships')]
# [('subTournamentName', "1924 Australasian Championships – Women's Doubles"), ('winnerName', 'Daphne Akhurst'), ('competitionClassName', "women's doubles"), ('yearlyTournamentName', '1924 Australasian Championships')]
# [('subTournamentName', "1924 Australasian Championships – Men's Doubles"), ('winnerName', 'James Anderson'), ('competitionClassName', "men's doubles"), ('yearlyTournamentName', '1924 Australasian Championships')]
# [('subTournamentName', '1924 Australasian Championships – Mixed Doubles'), ('winnerName', 'Daphne Akhurst'), ('competitionClassName', 'mixed doubles'), ('yearlyTournamentName', '1924 Australasian Championships')]
# [('subTournamentName', "1924 Australasian Championships – Men's Singles"), ('winnerName', 'James Anderson'), ('competitionClassName', "men's singles"), ('yearlyTournamentName', '1924 Australasian Championships')]
# [('subTournamentName', "1925 Australasian Championships – Women's Singles"), ('winnerName', 'Daphne Akhurst'), ('competitionClassName', "women's singles"), ('yearlyTournamentName', '1925 Australasian Championships')]
# [('subTournamentName', "1925 Australasian Championships – Men's Singles"), ('winnerName', 'James Anderson'), ('competitionClassName', "men's singles"), ('yearlyTournamentName', '1925 Australasian Championships')]
# [('subTournamentName', "1925 Australasian Championships – Women's Doubles"), ('winnerName', 'Daphne Akhurst'), ('competitionClassName', "women's doubles"), ('yearlyTournamentName', '1925 Australasian Championships')]
# [('subTournamentName', '1925 Australasian Championships – Mixed Doubles'), ('winnerName', 'Daphne Akhurst'), ('competitionClassName', 'mixed doubles'), ('yearlyTournamentName', '1925 Australasian Championships')]
# [('subTournamentName', "1925 Australasian Championships – Men's Doubles"), ('winnerName', "Pat O'Hara Wood"), ('competitionClassName', "men's doubles"), ('yearlyTournamentName', '1925 Australasian Championships')]
# [('subTournamentName', "1925 French Championships – Men's Singles"), ('winnerName', 'René Lacoste'), ('competitionClassName', "men's singles"), ('yearlyTournamentName', '1925 French Championships')]
# [('subTournamentName', "1925 French Championships – Women's Singles"), ('winnerName', 'Suzanne Lenglen'), ('competitionClassName', "women's singles"), ('yearlyTournamentName', '1925 French Championships')]
# [('subTournamentName', "1926 Australasian Championships – Women's Singles"), ('winnerName', 'Daphne Akhurst'), ('competitionClassName', "women's singles"), ('yearlyTournamentName', '1926 Australasian Championships')]
# [('subTournamentName', "1926 Australasian Championships – Men's Doubles"), ('winnerName', 'John Hawkes'), ('competitionClassName', "men's doubles"), ('yearlyTournamentName', '1926 Australasian Championships')]
# [('subTournamentName', '1926 Australasian Championships  - Womens Doubles'), ('winnerName', 'Esna Boyd'), ('competitionClassName', "women's doubles"), ('yearlyTournamentName', '1926 Australasian Championships')]
# [('subTournamentName', "1926 Australasian Championships – Men's Singles"), ('winnerName', 'John Hawkes'), ('competitionClassName', "men's singles"), ('yearlyTournamentName', '1926 Australasian Championships')]
# [('subTournamentName', '1926 Australasian Championships – Mixed Doubles'), ('winnerName', 'Esna Boyd'), ('competitionClassName', 'mixed doubles'), ('yearlyTournamentName', '1926 Australasian Championships')]
# [('subTournamentName', "1926 French Championships – Men's Singles"), ('winnerName', 'Henri Cochet'), ('competitionClassName', "men's singles"), ('yearlyTournamentName', '1926 French Championships')]
# [('subTournamentName', "1926 French Championships – Women's Singles"), ('winnerName', 'Suzanne Lenglen'), ('competitionClassName', "women's singles"), ('yearlyTournamentName', '1926 French Championships')]
# [('subTournamentName', "1927 Australian Championships – Men's Doubles"), ('winnerName', 'John Hawkes'), ('competitionClassName', "men's doubles"), ('yearlyTournamentName', '1927 Australian Championships')]
# [('subTournamentName', '1927 Australian Championships – Mixed Doubles'), ('winnerName', 'Esna Boyd'), ('competitionClassName', 'mixed doubles'), ('yearlyTournamentName', '1927 Australian Championships')]
# [('subTournamentName', "1927 Australian Championships – Men's Singles"), ('winnerName', 'Gerald Patterson'), ('competitionClassName', "men's singles"), ('yearlyTournamentName', '1927 Australian Championships')]
# [('subTournamentName', "1927 Australian Championships – Women's Doubles"), ('winnerName', 'Louie Bickerton'), ('competitionClassName', "women's doubles"), ('yearlyTournamentName', '1927 Australian Championships')]
# [('subTournamentName', "1927 Australian Championships – Women's Singles"), ('winnerName', 'Esna Boyd'), ('competitionClassName', "women's singles"), ('yearlyTournamentName', '1927 Australian Championships')]
# [('subTournamentName', "1927 French Championships – Men's Singles"), ('winnerName', 'René Lacoste'), ('competitionClassName', "men's singles"), ('yearlyTournamentName', '1927 French Championships')]
# [('subTournamentName', "1927 French Championships – Women's Singles"), ('winnerName', 'Kea Bouman'), ('competitionClassName', "women's singles"), ('yearlyTournamentName', '1927 French Championships')]
# [('subTournamentName', "1927 U.S. National Championships – Men's Singles"), ('winnerName', 'René Lacoste'), ('competitionClassName', "men's singles"), ('yearlyTournamentName', '1927 U.S. National Championships')]
# [('subTournamentName', "1927 U.S. National Championships – Women's Singles"), ('winnerName', 'Helen Wills'), ('competitionClassName', "women's singles"), ('yearlyTournamentName', '1927 U.S. National Championships')]
# [('subTournamentName', "1928 Australian Championships – Men's Doubles"), ('winnerName', 'Jean Borotra'), ('competitionClassName', "men's doubles"), ('yearlyTournamentName', '1928 Australian Championships')]
# [('subTournamentName', "1928 Australian Championships – Women's Doubles"), ('winnerName', 'Daphne Akhurst'), ('competitionClassName', "women's doubles"), ('yearlyTournamentName', '1928 Australian Championships')]
# [('subTournamentName', "1928 Australian Championships – Men's Singles"), ('winnerName', 'Jean Borotra'), ('competitionClassName', "men's singles"), ('yearlyTournamentName', '1928 Australian Championships')]
# [('subTournamentName', '1928 Australian Championships – Mixed Doubles'), ('winnerName', 'Daphne Akhurst'), ('competitionClassName', 'mixed doubles'), ('yearlyTournamentName', '1928 Australian Championships')]
# [('subTournamentName', "1928 Australian Championships – Women's Singles"), ('winnerName', 'Daphne Akhurst'), ('competitionClassName', "women's singles"), ('yearlyTournamentName', '1928 Australian Championships')]
# [('subTournamentName', "1928 French Championships – Women's Singles"), ('winnerName', 'Helen Wills'), ('competitionClassName', "women's singles"), ('yearlyTournamentName', '1928 French Championships')]
# [('subTournamentName', "1928 French Championships – Men's Singles"), ('winnerName', 'Henri Cochet'), ('competitionClassName', "men's singles"), ('yearlyTournamentName', '1928 French Championships')]
# [('subTournamentName', "1928 U.S. National Championships – Women's Singles"), ('winnerName', 'Helen Wills'), ('competitionClassName', "women's singles"), ('yearlyTournamentName', '1928 U.S. National Championships')]
# [('subTournamentName', "1928 U.S. National Championships – Men's Singles"), ('winnerName', 'Henri Cochet'), ('competitionClassName', "men's singles"), ('yearlyTournamentName', '1928 U.S. National Championships')]
# [('subTournamentName', "1929 Australian Championships – Men's Singles"), ('winnerName', 'Colin Gregory'), ('competitionClassName', "men's singles"), ('yearlyTournamentName', '1929 Australian Championships')]
# [('subTournamentName', "1929 Australian Championships – Women's Singles"), ('winnerName', 'Daphne Akhurst'), ('competitionClassName', "women's singles"), ('yearlyTournamentName', '1929 Australian Championships')]
# [('subTournamentName', "1929 Australian Championships – Women's Doubles"), ('winnerName', 'Daphne Akhurst'), ('competitionClassName', "women's doubles"), ('yearlyTournamentName', '1929 Australian Championships')]
# [('subTournamentName', '1929 Australian Championships – Mixed Doubles'), ('winnerName', 'Daphne Akhurst'), ('competitionClassName', 'mixed doubles'), ('yearlyTournamentName', '1929 Australian Championships')]
# [('subTournamentName', "1929 Australian Championships – Men's Doubles"), ('winnerName', 'Jack Crawford'), ('competitionClassName', "men's doubles"), ('yearlyTournamentName', '1929 Australian Championships')]
# [('subTournamentName', "1929 French Championships – Women's Doubles"), ('winnerName', 'Lilí Álvarez'), ('competitionClassName', "women's doubles"), ('yearlyTournamentName', '1929 French Championships')]
# [('subTournamentName', "1929 French Championships – Men's Doubles"), ('winnerName', 'René Lacoste'), ('competitionClassName', "men's doubles"), ('yearlyTournamentName', '1929 French Championships')]
# [('subTournamentName', '1929 French Championships – Mixed Doubles'), ('winnerName', 'Eileen Bennett Whittingstall'), ('competitionClassName', 'mixed doubles'), ('yearlyTournamentName', '1929 French Championships')]
# [('subTournamentName', "1929 French Championships – Men's Singles"), ('winnerName', 'René Lacoste'), ('competitionClassName', "men's singles"), ('yearlyTournamentName', '1929 French Championships')]
# [('subTournamentName', "1929 French Championships – Women's Singles"), ('winnerName', 'Helen Wills'), ('competitionClassName', "women's singles"), ('yearlyTournamentName', '1929 French Championships')]
# [('subTournamentName', "1930 Australian Championships – Women's Singles"), ('winnerName', 'Daphne Akhurst'), ('competitionClassName', "women's singles"), ('yearlyTournamentName', '1930 Australian Championships')]
# [('subTournamentName', "1930 Australian Championships – Men's Doubles"), ('winnerName', 'Jack Crawford'), ('competitionClassName', "men's doubles"), ('yearlyTournamentName', '1930 Australian Championships')]
# [('subTournamentName', '1930 Australian Championships – Mixed Doubles'), ('winnerName', 'Nell Hall Hopman'), ('competitionClassName', 'mixed doubles'), ('yearlyTournamentName', '1930 Australian Championships')]
# [('subTournamentName', "1930 Australian Championships – Men's Singles"), ('winnerName', 'Edgar Moon'), ('competitionClassName', "men's singles"), ('yearlyTournamentName', '1930 Australian Championships')]
# [('subTournamentName', "1930 Australian Championships – Women's Doubles"), ('winnerName', 'Emily Hood Westacott'), ('competitionClassName', "women's doubles"), ('yearlyTournamentName', '1930 Australian Championships')]
# [('subTournamentName', "1930 French Championships – Men's Singles"), ('winnerName', 'Henri Cochet'), ('competitionClassName', "men's singles"), ('yearlyTournamentName', '1930 French Championships')]
# [('subTournamentName', "1930 French Championships – Women's Singles"), ('winnerName', 'Helen Wills'), ('competitionClassName', "women's singles"), ('yearlyTournamentName', '1930 French Championships')]
# [('subTournamentName', "1931 Australian Championships – Men's Singles"), ('winnerName', 'Jack Crawford'), ('competitionClassName', "men's singles"), ('yearlyTournamentName', '1931 Australian Championships')]
# [('subTournamentName', "1931 Australian Championships – Women's Singles"), ('winnerName', 'Coral Buttsworth'), ('competitionClassName', "women's singles"), ('yearlyTournamentName', '1931 Australian Championships')]
# [('subTournamentName', "1931 Australian Championships – Women's Doubles"), ('winnerName', 'Louie Bickerton'), ('competitionClassName', "women's doubles"), ('yearlyTournamentName', '1931 Australian Championships')]
# [('subTournamentName', "1931 Australian Championships – Men's Doubles"), ('winnerName', 'Charles Donohoe'), ('competitionClassName', "men's doubles"), ('yearlyTournamentName', '1931 Australian Championships')]
# [('subTournamentName', '1931 Australian Championships – Mixed Doubles'), ('winnerName', 'Marjorie Cox Crawford'), ('competitionClassName', 'mixed doubles'), ('yearlyTournamentName', '1931 Australian Championships')]
# [('subTournamentName', "1931 French Championships – Men's Singles"), ('winnerName', 'Jean Borotra'), ('competitionClassName', "men's singles"), ('yearlyTournamentName', '1931 French Championships')]
# [('subTournamentName', "1931 French Championships – Women's Singles"), ('winnerName', 'Cilly Aussem'), ('competitionClassName', "women's singles"), ('yearlyTournamentName', '1931 French Championships')]
# [('subTournamentName', "1932 Australian Championships – Women's Doubles"), ('winnerName', 'Coral Buttsworth'), ('competitionClassName', "women's doubles"), ('yearlyTournamentName', '1932 Australian Championships')]
# [('subTournamentName', "1932 Australian Championships – Men's Doubles"), ('winnerName', 'Jack Crawford'), ('competitionClassName', "men's doubles"), ('yearlyTournamentName', '1932 Australian Championships')]
# [('subTournamentName', "1932 Australian Championships – Men's Singles"), ('winnerName', 'Jack Crawford'), ('competitionClassName', "men's singles"), ('yearlyTournamentName', '1932 Australian Championships')]
# [('subTournamentName', "1932 Australian Championships – Women's Singles"), ('winnerName', 'Coral Buttsworth'), ('competitionClassName', "women's singles"), ('yearlyTournamentName', '1932 Australian Championships')]
# [('subTournamentName', '1932 Australian Championships – Mixed Doubles'), ('winnerName', 'Marjorie Cox Crawford'), ('competitionClassName', 'mixed doubles'), ('yearlyTournamentName', '1932 Australian Championships')]
# [('subTournamentName', "1932 French Championships – Women's Singles"), ('winnerName', 'Helen Wills'), ('competitionClassName', "women's singles"), ('yearlyTournamentName', '1932 French Championships')]
# [('subTournamentName', "1932 French Championships – Men's Singles"), ('winnerName', 'Henri Cochet'), ('competitionClassName', "men's singles"), ('yearlyTournamentName', '1932 French Championships')]
# [('subTournamentName', "1933 Australian Championships – Women's Doubles"), ('winnerName', 'Margaret Molesworth'), ('competitionClassName', "women's doubles"), ('yearlyTournamentName', '1933 Australian Championships')]
# [('subTournamentName', '1933 Australian Championships – Mixed Doubles'), ('winnerName', 'Marjorie Cox Crawford'), ('competitionClassName', 'mixed doubles'), ('yearlyTournamentName', '1933 Australian Championships')]
# [('subTournamentName', "1933 Australian Championships – Men's Doubles"), ('winnerName', 'Keith Gledhill'), ('competitionClassName', "men's doubles"), ('yearlyTournamentName', '1933 Australian Championships')]
# [('subTournamentName', "1933 Australian Championships – Men's Singles"), ('winnerName', 'Jack Crawford'), ('competitionClassName', "men's singles"), ('yearlyTournamentName', '1933 Australian Championships')]
# [('subTournamentName', "1933 Australian Championships – Women's Singles"), ('winnerName', 'Joan Hartigan'), ('competitionClassName', "women's singles"), ('yearlyTournamentName', '1933 Australian Championships')]
# [('subTournamentName', "1933 French Championships – Men's Singles"), ('winnerName', 'Jack Crawford'), ('competitionClassName', "men's singles"), ('yearlyTournamentName', '1933 French Championships')]
# [('subTournamentName', "1933 French Championships – Women's Singles"), ('winnerName', 'Margaret Scriven'), ('competitionClassName', "women's singles"), ('yearlyTournamentName', '1933 French Championships')]
# [('subTournamentName', '1934 Australian Championships – Mixed Doubles'), ('winnerName', 'Joan Hartigan'), ('competitionClassName', 'mixed doubles'), ('yearlyTournamentName', '1934 Australian Championships')]
# [('subTournamentName', "1934 Australian Championships – Men's Doubles"), ('winnerName', 'Pat Hughes'), ('competitionClassName', "men's doubles"), ('yearlyTournamentName', '1934 Australian Championships')]
# [('subTournamentName', "1934 Australian Championships – Women's Doubles"), ('winnerName', 'Margaret Molesworth'), ('competitionClassName', "women's doubles"), ('yearlyTournamentName', '1934 Australian Championships')]
# [('subTournamentName', "1934 Australian Championships – Women's Singles"), ('winnerName', 'Joan Hartigan'), ('competitionClassName', "women's singles"), ('yearlyTournamentName', '1934 Australian Championships')]
# [('subTournamentName', "1934 Australian Championships – Men's Singles"), ('winnerName', 'Fred Perry'), ('competitionClassName', "men's singles"), ('yearlyTournamentName', '1934 Australian Championships')]
# [('subTournamentName', "1934 French Championships – Men's Singles"), ('winnerName', 'Gottfried von Cramm'), ('competitionClassName', "men's singles"), ('yearlyTournamentName', '1934 French Championships')]
# [('subTournamentName', "1934 French Championships – Women's Singles"), ('winnerName', 'Margaret Scriven'), ('competitionClassName', "women's singles"), ('yearlyTournamentName', '1934 French Championships')]
# [('subTournamentName', "1935 Australian Championships – Men's Singles"), ('winnerName', 'Jack Crawford'), ('competitionClassName', "men's singles"), ('yearlyTournamentName', '1935 Australian Championships')]
# [('subTournamentName', "1935 Australian Championships – Women's Singles"), ('winnerName', 'Dorothy Round'), ('competitionClassName', "women's singles"), ('yearlyTournamentName', '1935 Australian Championships')]
# [('subTournamentName', "1935 Australian Championships – Women's Doubles"), ('winnerName', 'Evelyn Dearman'), ('competitionClassName', "women's doubles"), ('yearlyTournamentName', '1935 Australian Championships')]
# [('subTournamentName', '1935 Australian Championships – Mixed Doubles'), ('winnerName', 'Louie Bickerton'), ('competitionClassName', 'mixed doubles'), ('yearlyTournamentName', '1935 Australian Championships')]
# [('subTournamentName', "1935 Australian Championships – Men's Doubles"), ('winnerName', 'Jack Crawford'), ('competitionClassName', "men's doubles"), ('yearlyTournamentName', '1935 Australian Championships')]
# [('subTournamentName', "1935 French Championships – Men's Singles"), ('winnerName', 'Fred Perry'), ('competitionClassName', "men's singles"), ('yearlyTournamentName', '1935 French Championships')]
# [('subTournamentName', "1935 French Championships – Women's Singles"), ('winnerName', 'Hilde Krahwinkel Sperling'), ('competitionClassName', "women's singles"), ('yearlyTournamentName', '1935 French Championships')]
# [('subTournamentName', "1936 Australian Championships – Men's Singles"), ('winnerName', 'Adrian Quist'), ('competitionClassName', "men's singles"), ('yearlyTournamentName', '1936 Australian Championships')]
# [('subTournamentName', "1936 Australian Championships – Women's Singles"), ('winnerName', 'Joan Hartigan'), ('competitionClassName', "women's singles"), ('yearlyTournamentName', '1936 Australian Championships')]
# [('subTournamentName', "1936 Australian Championships – Women's Doubles"), ('winnerName', 'Thelma Coyne Long'), ('competitionClassName', "women's doubles"), ('yearlyTournamentName', '1936 Australian Championships')]
# [('subTournamentName', '1936 Australian Championships – Mixed Doubles'), ('winnerName', 'Nell Hall Hopman'), ('competitionClassName', 'mixed doubles'), ('yearlyTournamentName', '1936 Australian Championships')]
# [('subTournamentName', "1936 Australian Championships – Men's Doubles"), ('winnerName', 'Adrian Quist'), ('competitionClassName', "men's doubles"), ('yearlyTournamentName', '1936 Australian Championships')]
# [('subTournamentName', "1936 French Championships – Women's Singles"), ('winnerName', 'Hilde Krahwinkel Sperling'), ('competitionClassName', "women's singles"), ('yearlyTournamentName', '1936 French Championships')]
# [('subTournamentName', "1936 French Championships – Men's Singles"), ('winnerName', 'Gottfried von Cramm'), ('competitionClassName', "men's singles"), ('yearlyTournamentName', '1936 French Championships')]
# [('subTournamentName', "1937 Australian Championships – Men's Singles"), ('winnerName', 'Vivian McGrath'), ('competitionClassName', "men's singles"), ('yearlyTournamentName', '1937 Australian Championships')]
# [('subTournamentName', "1937 Australian Championships – Women's Doubles"), ('winnerName', 'Thelma Coyne Long'), ('competitionClassName', "women's doubles"), ('yearlyTournamentName', '1937 Australian Championships')]
# [('subTournamentName', "1937 Australian Championships – Women's Singles"), ('winnerName', 'Nancye Wynne Bolton'), ('competitionClassName', "women's singles"), ('yearlyTournamentName', '1937 Australian Championships')]
# [('subTournamentName', '1937 Australian Championships – Mixed Doubles'), ('winnerName', 'Nell Hall Hopman'), ('competitionClassName', 'mixed doubles'), ('yearlyTournamentName', '1937 Australian Championships')]
# [('subTournamentName', "1937 Australian Championships – Men's Doubles"), ('winnerName', 'Adrian Quist'), ('competitionClassName', "men's doubles"), ('yearlyTournamentName', '1937 Australian Championships')]
# [('subTournamentName', "1937 French Championships – Men's Singles"), ('winnerName', 'Henner Henkel'), ('competitionClassName', "men's singles"), ('yearlyTournamentName', '1937 French Championships')]
# [('subTournamentName', "1937 French Championships – Women's Singles"), ('winnerName', 'Hilde Krahwinkel Sperling'), ('competitionClassName', "women's singles"), ('yearlyTournamentName', '1937 French Championships')]
# [('subTournamentName', '1938 Australian Championships – Mixed Doubles'), ('winnerName', 'Margaret Wilson'), ('competitionClassName', 'mixed doubles'), ('yearlyTournamentName', '1938 Australian Championships')]
# [('subTournamentName', "1938 Australian Championships – Women's Doubles"), ('winnerName', 'Thelma Coyne Long'), ('competitionClassName', "women's doubles"), ('yearlyTournamentName', '1938 Australian Championships')]
# [('subTournamentName', "1938 Australian Championships – Women's Singles"), ('winnerName', 'Dorothy Cheney'), ('competitionClassName', "women's singles"), ('yearlyTournamentName', '1938 Australian Championships')]
# [('subTournamentName', "1938 Australian Championships – Men's Singles"), ('winnerName', 'Don Budge'), ('competitionClassName', "men's singles"), ('yearlyTournamentName', '1938 Australian Championships')]
# [('subTournamentName', "1938 Australian Championships – Men's Doubles"), ('winnerName', 'John Bromwich'), ('competitionClassName', "men's doubles"), ('yearlyTournamentName', '1938 Australian Championships')]
# [('subTournamentName', "1938 French Championships – Men's Singles"), ('winnerName', 'Don Budge'), ('competitionClassName', "men's singles"), ('yearlyTournamentName', '1938 French Championships')]
# [('subTournamentName', "1938 French Championships – Women's Singles"), ('winnerName', 'Simonne Mathieu'), ('competitionClassName', "women's singles"), ('yearlyTournamentName', '1938 French Championships')]
# [('subTournamentName', "1939 Australian Championships – Women's Singles"), ('winnerName', 'Emily Hood Westacott'), ('competitionClassName', "women's singles"), ('yearlyTournamentName', '1939 Australian Championships')]
# [('subTournamentName', '1939 Australian Championships – Mixed Doubles'), ('winnerName', 'Nell Hall Hopman'), ('competitionClassName', 'mixed doubles'), ('yearlyTournamentName', '1939 Australian Championships')]
# [('subTournamentName', "1939 Australian Championships – Men's Doubles"), ('winnerName', 'John Bromwich'), ('competitionClassName', "men's doubles"), ('yearlyTournamentName', '1939 Australian Championships')]
# [('subTournamentName', "1939 Australian Championships – Men's Singles"), ('winnerName', 'John Bromwich'), ('competitionClassName', "men's singles"), ('yearlyTournamentName', '1939 Australian Championships')]
# [('subTournamentName', "1939 Australian Championships – Women's Doubles"), ('winnerName', 'Thelma Coyne Long'), ('competitionClassName', "women's doubles"), ('yearlyTournamentName', '1939 Australian Championships')]
# [('subTournamentName', "1940 Australian Championships – Women's Singles"), ('winnerName', 'Nancye Wynne Bolton'), ('competitionClassName', "women's singles"), ('yearlyTournamentName', '1940 Australian Championships')]
# [('subTournamentName', "1940 Australian Championships – Men's Doubles"), ('winnerName', 'John Bromwich'), ('competitionClassName', "men's doubles"), ('yearlyTournamentName', '1940 Australian Championships')]
# [('subTournamentName', "1940 Australian Championships – Men's Singles"), ('winnerName', 'Adrian Quist'), ('competitionClassName', "men's singles"), ('yearlyTournamentName', '1940 Australian Championships')]
# [('subTournamentName', "1940 Australian Championships – Women's Doubles"), ('winnerName', 'Thelma Coyne Long'), ('competitionClassName', "women's doubles"), ('yearlyTournamentName', '1940 Australian Championships')]
# [('subTournamentName', '1940 Australian Championships – Mixed Doubles'), ('winnerName', 'Nancye Wynne Bolton'), ('competitionClassName', 'mixed doubles'), ('yearlyTournamentName', '1940 Australian Championships')]
# [('subTournamentName', "1946 Australian Championships – Men's Singles"), ('winnerName', 'John Bromwich'), ('competitionClassName', "men's singles"), ('yearlyTournamentName', '1946 Australian Championships')]
# [('subTournamentName', "1946 Australian Championships – Women's Singles"), ('winnerName', 'Nancye Wynne Bolton'), ('competitionClassName', "women's singles"), ('yearlyTournamentName', '1946 Australian Championships')]
# [('subTournamentName', "1946 Australian Championships – Women's Doubles"), ('winnerName', 'Mary Hawton'), ('competitionClassName', "women's doubles"), ('yearlyTournamentName', '1946 Australian Championships')]
# [('subTournamentName', '1946 Australian Championships – Mixed Doubles'), ('winnerName', 'Nancye Wynne Bolton'), ('competitionClassName', 'mixed doubles'), ('yearlyTournamentName', '1946 Australian Championships')]
# [('subTournamentName', "1946 French Championships – Men's Singles"), ('winnerName', 'Marcel Bernard'), ('competitionClassName', "men's singles"), ('yearlyTournamentName', '1946 French Championships')]
# [('subTournamentName', "1946 French Championships – Women's Singles"), ('winnerName', 'Margaret Osborne duPont'), ('competitionClassName', "women's singles"), ('yearlyTournamentName', '1946 French Championships')]
# [('subTournamentName', "1946 Wimbledon Championships – Women's Singles"), ('winnerName', 'Pauline Betz'), ('competitionClassName', "women's singles"), ('yearlyTournamentName', '1946 Wimbledon Championships')]
# 200

# %% [markdown]
# ##### The data is incomplete, even 1938 has no Wimbledon neither US open ...

# %% [markdown]
# ##### Now trying to solve countryForSport problem that escludes one matching, is the same problem: Data Missing?

# %%
# write your queries
# Consider the country for sport property of the tennis player (NO Country of citizenship). 
# Return the countries with at least one player who won at least one edition of each Grand Slam (the result set must be a list of country IRI and label).

# [('p', 'http://www.wikidata.org/prop/direct/P1532'), ('name', 'country for sport')]

# P31 ('instance of')
# P527 ('has part')
# P1346 ('winner')

#[('obj', 'http://www.wikidata.org/entity/Q43605'), ('objName', 'French Open')]
#[('obj', 'http://www.wikidata.org/entity/Q123577'), ('objName', 'US Open')]
#[('obj', 'http://www.wikidata.org/entity/Q41520'), ('objName', 'Wimbledon Championships')]
#[('obj', 'http://www.wikidata.org/entity/Q60874'), ('objName', 'Australian Open')]

# final query with country for sport 

queryString = """

PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
SELECT DISTINCT ?winner ?winnerName ?countryForSport ?competitionClassName ?year (COUNT(*) as ?tot)
WHERE {
   VALUES (?tournament){
       (wd:Q43605)
       (wd:Q123577)
       (wd:Q41520)
       (wd:Q60874)
   }
   # ?yearlyTournament wdt:P31 ?tournament.
   # ?yearlyTournament wdt:P527 ?subTournament.
   # ?subTournament wdt:P1346 ?winner;
                   wdt:P2094 ?competitionClass.
   
   # ?winner wdt:P1532 ?countryForSport.
   
   # get the label 
   # ?tournament sc:name ?tournamentName .
   # ?yearlyTournament sc:name ?yearlyTournamentName .
   # ?subTournament sc:name ?subTournamentName.
   # ?winner sc:name ?winnerName.
   # ?competitionClass sc:name ?competitionClassName.
   
   BIND(xsd:integer(SUBSTR(?yearlyTournamentName,0,4)) as ?year)
}
GROUP BY ?winner ?winnerName ?countryForSport ?competitionClassName ?year
HAVING (count(*) >=4)
ORDER BY DESC (?year)
LIMIT 100

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('winner', 'http://www.wikidata.org/entity/Q11662'), ('winnerName', 'Steffi Graf'), ('countryForSport', 'http://www.wikidata.org/entity/Q183'), ('competitionClassName', "women's singles"), ('year', '1988'), ('tot', '4')]
# 1

# %%
# write your queries
# Consider the country for sport property of the tennis player (NO Country of citizenship). 
# Return the countries with at least one player who won at least one edition of each Grand Slam (the result set must be a list of country IRI and label).

# [('p', 'http://www.wikidata.org/prop/direct/P1532'), ('name', 'country for sport')]

# P31 ('instance of')
# P527 ('has part')
# P1346 ('winner')

#[('obj', 'http://www.wikidata.org/entity/Q43605'), ('objName', 'French Open')]
#[('obj', 'http://www.wikidata.org/entity/Q123577'), ('objName', 'US Open')]
#[('obj', 'http://www.wikidata.org/entity/Q41520'), ('objName', 'Wimbledon Championships')]
#[('obj', 'http://www.wikidata.org/entity/Q60874'), ('objName', 'Australian Open')]

# final query without country for sport 

queryString = """

PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
SELECT DISTINCT ?winner ?winnerName ?competitionClassName ?year (COUNT(*) as ?tot)
WHERE {
   VALUES (?tournament){
       (wd:Q43605)
       (wd:Q123577)
       (wd:Q41520)
       (wd:Q60874)
   }
   # ?yearlyTournament wdt:P31 ?tournament.
   # ?yearlyTournament wdt:P527 ?subTournament.
   # ?subTournament wdt:P1346 ?winner;
                   wdt:P2094 ?competitionClass.
   
   #?winner wdt:P1532 ?countryForSport.
   
   # get the label 
   # ?tournament sc:name ?tournamentName .
   # ?yearlyTournament sc:name ?yearlyTournamentName .
   # ?subTournament sc:name ?subTournamentName.
   # ?winner sc:name ?winnerName.
   # ?competitionClass sc:name ?competitionClassName.
   
   BIND(xsd:integer(SUBSTR(?yearlyTournamentName,0,4)) as ?year)
}
GROUP BY ?winner ?winnerName ?competitionClassName ?year
HAVING (count(*) >=4)
ORDER BY DESC (?year)
LIMIT 100

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('winner', 'http://www.wikidata.org/entity/Q24574661'), ('winnerName', 'Diede de Groot'), ('competitionClassName', "wheelchair tennis women's doubles"), ('year', '2019'), ('tot', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q11662'), ('winnerName', 'Steffi Graf'), ('competitionClassName', "women's singles"), ('year', '1988'), ('tot', '4')]
# 2

# %%
# write your queries
# Consider the country for sport property of the tennis player (NO Country of citizenship). 
# Return the countries with at least one player who won at least one edition of each Grand Slam (the result set must be a list of country IRI and label).

# [('p', 'http://www.wikidata.org/prop/direct/P1532'), ('name', 'country for sport')]
# ('winner', 'http://www.wikidata.org/entity/Q24574661'), ('winnerName', 'Diede de Groot'), 

# checking Diede de Groot's Q24574661 properties
queryString = """

PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
SELECT DISTINCT ?p ?pName ?o ?oName
WHERE {
   wd:Q24574661 ?p ?o .
   # get the label 
   # ?p sc:name ?pName.
   # ?o sc:name ?oName.
}
LIMIT 50
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P1411'), ('pName', 'nominated for'), ('o', 'http://www.wikidata.org/entity/Q6501370'), ('oName', 'Laureus World Sports Award for Sportsperson of the Year with a Disability')]
# [('p', 'http://www.wikidata.org/prop/direct/P27'), ('pName', 'country of citizenship'), ('o', 'http://www.wikidata.org/entity/Q29999'), ('oName', 'Kingdom of the Netherlands')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('o', 'http://www.wikidata.org/entity/Q5'), ('oName', 'human')]
# [('p', 'http://www.wikidata.org/prop/direct/P19'), ('pName', 'place of birth'), ('o', 'http://www.wikidata.org/entity/Q5128'), ('oName', 'Woerden')]
# [('p', 'http://www.wikidata.org/prop/direct/P21'), ('pName', 'sex or gender'), ('o', 'http://www.wikidata.org/entity/Q6581072'), ('oName', 'female')]
# [('p', 'http://www.wikidata.org/prop/direct/P641'), ('pName', 'sport'), ('o', 'http://www.wikidata.org/entity/Q1153025'), ('oName', 'wheelchair tennis')]
# [('p', 'http://www.wikidata.org/prop/direct/P106'), ('pName', 'occupation'), ('o', 'http://www.wikidata.org/entity/Q18814798'), ('oName', 'wheelchair tennis player')]
# [('p', 'http://www.wikidata.org/prop/direct/P551'), ('pName', 'residence'), ('o', 'http://www.wikidata.org/entity/Q33470616'), ('oName', 'Oudewater')]
# 8

# %%
# write your queries
# Consider the country for sport property of the tennis player (NO Country of citizenship). 
# Return the countries with at least one player who won at least one edition of each Grand Slam (the result set must be a list of country IRI and label).

# [('p', 'http://www.wikidata.org/prop/direct/P1532'), ('name', 'country for sport')]
# ('winner', 'http://www.wikidata.org/entity/Q24574661'), ('winnerName', 'Diede de Groot'), 

# checking Diede de Groot's Q24574661 properties
# without ?o

queryString = """

PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
SELECT DISTINCT ?p ?pName
WHERE {
   wd:Q24574661 ?p ?o .
   # get the label 
   # ?p sc:name ?pName.
   #?o sc:name ?oName.
}
LIMIT 50
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P106'), ('pName', 'occupation')]
# [('p', 'http://www.wikidata.org/prop/direct/P1352'), ('pName', 'ranking')]
# [('p', 'http://www.wikidata.org/prop/direct/P1411'), ('pName', 'nominated for')]
# [('p', 'http://www.wikidata.org/prop/direct/P18'), ('pName', 'image')]
# [('p', 'http://www.wikidata.org/prop/direct/P19'), ('pName', 'place of birth')]
# [('p', 'http://www.wikidata.org/prop/direct/P2002'), ('pName', 'Twitter username')]
# [('p', 'http://www.wikidata.org/prop/direct/P2003'), ('pName', 'Instagram username')]
# [('p', 'http://www.wikidata.org/prop/direct/P2013'), ('pName', 'Facebook ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P21'), ('pName', 'sex or gender')]
# [('p', 'http://www.wikidata.org/prop/direct/P2671'), ('pName', 'Google Knowledge Graph ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P27'), ('pName', 'country of citizenship')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('p', 'http://www.wikidata.org/prop/direct/P373'), ('pName', 'Commons category')]
# [('p', 'http://www.wikidata.org/prop/direct/P551'), ('pName', 'residence')]
# [('p', 'http://www.wikidata.org/prop/direct/P555'), ('pName', 'doubles record')]
# [('p', 'http://www.wikidata.org/prop/direct/P564'), ('pName', 'singles record')]
# [('p', 'http://www.wikidata.org/prop/direct/P569'), ('pName', 'date of birth')]
# [('p', 'http://www.wikidata.org/prop/direct/P641'), ('pName', 'sport')]
# [('p', 'http://www.wikidata.org/prop/direct/P856'), ('pName', 'official website')]
# [('p', 'http://www.wikidata.org/prop/direct/P8618'), ('pName', 'ITF player ID 2020')]
# [('p', 'http://www.wikidata.org/prop/direct/P7550'), ('pName', 'Paralympic.org athlete ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P4299'), ('pName', 'ITF wheelchair player ID until 2019')]
# 22

# %% [markdown]
# ##### No problem, there is no property countryForSport in KB for Q24574661 ('Diede de Groot')

# %%
# write your queries
# Consider the country for sport property of the tennis player (NO Country of citizenship). 
# Return the countries with at least one player who won at least one edition of each Grand Slam (the result set must be a list of country IRI and label).

# [('p', 'http://www.wikidata.org/prop/direct/P1532'), ('name', 'country for sport')]

# P31 ('instance of')
# P527 ('has part')
# P1346 ('winner')

#[('obj', 'http://www.wikidata.org/entity/Q43605'), ('objName', 'French Open')]
#[('obj', 'http://www.wikidata.org/entity/Q123577'), ('objName', 'US Open')]
#[('obj', 'http://www.wikidata.org/entity/Q41520'), ('objName', 'Wimbledon Championships')]
#[('obj', 'http://www.wikidata.org/entity/Q60874'), ('objName', 'Australian Open')]


# 1) checking if in all seasons if someone has won all edition of each Grand Slam in the same category 
# 2) finding the winners of each GS tournament in each category
# 3) selecting only those who have 4 or more wins in the same category
# -> 4) grouping and then getting distinct countryForSportName 

queryString = """

PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
SELECT DISTINCT ?countryForSport ?countryForSportName
WHERE {
   VALUES (?tournament){
       (wd:Q43605)
       (wd:Q123577)
       (wd:Q41520)
       (wd:Q60874)
   }
   # ?yearlyTournament wdt:P31 ?tournament.
   # ?yearlyTournament wdt:P527 ?subTournament.
   # ?subTournament wdt:P1346 ?winner;
                   wdt:P2094 ?competitionClass.
   
   # ?winner wdt:P1532 ?countryForSport.
   
   # get the label 
   # ?tournament sc:name ?tournamentName .
   # ?yearlyTournament sc:name ?yearlyTournamentName .
   # ?subTournament sc:name ?subTournamentName.
   # ?winner sc:name ?winnerName.
   # ?competitionClass sc:name ?competitionClassName.
   
   # ?countryForSport sc:name ?countryForSportName
   
   BIND(xsd:integer(SUBSTR(?yearlyTournamentName,0,4)) as ?year)
}
GROUP BY ?countryForSport ?countryForSportName
HAVING (count(*) >=4)
LIMIT 100

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('countryForSport', 'http://www.wikidata.org/entity/Q215'), ('countryForSportName', 'Slovenia')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q218'), ('countryForSportName', 'Romania')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q28'), ('countryForSportName', 'Hungary')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q38'), ('countryForSportName', 'Italy')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q16'), ('countryForSportName', 'Canada')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q664'), ('countryForSportName', 'New Zealand')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q183'), ('countryForSportName', 'Germany')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q216923'), ('countryForSportName', 'Chinese Taipei')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q83286'), ('countryForSportName', 'Socialist Federal Republic of Yugoslavia')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q34'), ('countryForSportName', 'Sweden')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q403'), ('countryForSportName', 'Serbia')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q155'), ('countryForSportName', 'Brazil')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q212'), ('countryForSportName', 'Ukraine')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q31'), ('countryForSportName', 'Belgium')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q148'), ('countryForSportName', "People's Republic of China")]
# [('countryForSport', 'http://www.wikidata.org/entity/Q29'), ('countryForSportName', 'Spain')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q668'), ('countryForSportName', 'India')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q184'), ('countryForSportName', 'Belarus')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q40'), ('countryForSportName', 'Austria')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q142'), ('countryForSportName', 'France')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q224'), ('countryForSportName', 'Croatia')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q36'), ('countryForSportName', 'Poland')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q213'), ('countryForSportName', 'Czech Republic')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q29999'), ('countryForSportName', 'Kingdom of the Netherlands')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q408'), ('countryForSportName', 'Australia')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q30'), ('countryForSportName', 'United States of America')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q214'), ('countryForSportName', 'Slovakia')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q17'), ('countryForSportName', 'Japan')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q39'), ('countryForSportName', 'Switzerland')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q159'), ('countryForSportName', 'Russia')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q145'), ('countryForSportName', 'United Kingdom')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q33946'), ('countryForSportName', 'Czechoslovakia')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q15180'), ('countryForSportName', 'Soviet Union')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q211'), ('countryForSportName', 'Latvia')]
# 34

# %%
# write your queries
# Consider the country for sport property of the tennis player (NO Country of citizenship). 
# Return the countries with at least one player who won at least one edition of each Grand Slam (the result set must be a list of country IRI and label).

# [('p', 'http://www.wikidata.org/prop/direct/P1532'), ('name', 'country for sport')]

# P31 ('instance of')
# P527 ('has part')
# P1346 ('winner')

#[('obj', 'http://www.wikidata.org/entity/Q43605'), ('objName', 'French Open')]
#[('obj', 'http://www.wikidata.org/entity/Q123577'), ('objName', 'US Open')]
#[('obj', 'http://www.wikidata.org/entity/Q41520'), ('objName', 'Wimbledon Championships')]
#[('obj', 'http://www.wikidata.org/entity/Q60874'), ('objName', 'Australian Open')]

# 1) checking if in all seasons if someone has won all edition of each Grand Slam in the same category 
# 2) finding the winners of each GS tournament in each category
# 3) selecting only those who have 4 or more wins in the same category
# -> 4) grouping and then getting distinct countryForSportName 
#       GROUP BY corrected

queryString = """

PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
SELECT DISTINCT ?countryForSport ?countryForSportName ?year (COUNT(*) as ?tot)
WHERE {
   VALUES (?tournament){
       (wd:Q43605)
       (wd:Q123577)
       (wd:Q41520)
       (wd:Q60874)
   }
   # ?yearlyTournament wdt:P31 ?tournament.
   # ?yearlyTournament wdt:P527 ?subTournament.
   # ?subTournament wdt:P1346 ?winner;
                   wdt:P2094 ?competitionClass.
   
   # ?winner wdt:P1532 ?countryForSport.
   
   # get the label 
   # ?tournament sc:name ?tournamentName .
   # ?yearlyTournament sc:name ?yearlyTournamentName .
   # ?subTournament sc:name ?subTournamentName.
   # ?winner sc:name ?winnerName.
   # ?competitionClass sc:name ?competitionClassName.
   
   # ?countryForSport sc:name ?countryForSportName
   
   BIND(xsd:integer(SUBSTR(?yearlyTournamentName,0,4)) as ?year)
}
GROUP BY ?winner ?winnerName ?countryForSport ?countryForSportName ?competitionClassName ?year
HAVING (count(*) >=4)
ORDER BY DESC (?year)
LIMIT 100

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('countryForSport', 'http://www.wikidata.org/entity/Q183'), ('countryForSportName', 'Germany'), ('year', '1988'), ('tot', '4')]
# 1

# %%
# write your queries
# Consider the country for sport property of the tennis player (NO Country of citizenship). 
# Return the countries with at least one player who won at least one edition of each Grand Slam (the result set must be a list of country IRI and label).

# [('p', 'http://www.wikidata.org/prop/direct/P1532'), ('name', 'country for sport')]

# P31 ('instance of')
# P527 ('has part')
# P1346 ('winner')

#[('obj', 'http://www.wikidata.org/entity/Q43605'), ('objName', 'French Open')]
#[('obj', 'http://www.wikidata.org/entity/Q123577'), ('objName', 'US Open')]
#[('obj', 'http://www.wikidata.org/entity/Q41520'), ('objName', 'Wimbledon Championships')]
#[('obj', 'http://www.wikidata.org/entity/Q60874'), ('objName', 'Australian Open')]

# 1) checking if in all seasons if someone has won all edition of each Grand Slam in the same category 
# 2) finding the winners of each GS tournament in each category
# 3) selecting only those who have 4 or more wins in the same category
# 4) grouping and then getting distinct countryForSportName 
#    GROUP BY corrected
# -> 5) Cleaning result

queryString = """

PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
SELECT DISTINCT ?countryForSport ?countryForSportName
WHERE {
   VALUES (?tournament){
       (wd:Q43605)
       (wd:Q123577)
       (wd:Q41520)
       (wd:Q60874)
   }
   # ?yearlyTournament wdt:P31 ?tournament.
   # ?yearlyTournament wdt:P527 ?subTournament.
   # ?subTournament wdt:P1346 ?winner;
                   wdt:P2094 ?competitionClass.
   
   # ?winner wdt:P1532 ?countryForSport.
   
   # get the label 
   # ?tournament sc:name ?tournamentName .
   # ?yearlyTournament sc:name ?yearlyTournamentName .
   # ?subTournament sc:name ?subTournamentName.
   # ?winner sc:name ?winnerName.
   # ?competitionClass sc:name ?competitionClassName.
   
   # ?countryForSport sc:name ?countryForSportName
   
   BIND(xsd:integer(SUBSTR(?yearlyTournamentName,0,4)) as ?year)
}
GROUP BY ?winner ?winnerName ?countryForSport ?countryForSportName ?competitionClassName ?year
HAVING (count(*) >=4)
ORDER BY DESC (?year)
LIMIT 100

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('countryForSport', 'http://www.wikidata.org/entity/Q183'), ('countryForSportName', 'Germany')]
# 1

# %%
# write your final query
# Consider the country for sport property of the tennis player (NO Country of citizenship). 
# Return the countries with at least one player who won at least one edition of each Grand Slam (the result set must be a list of country IRI and label).

# [('p', 'http://www.wikidata.org/prop/direct/P1532'), ('name', 'country for sport')]

# P31 ('instance of')
# P527 ('has part')
# P1346 ('winner')

#[('obj', 'http://www.wikidata.org/entity/Q43605'), ('objName', 'French Open')]
#[('obj', 'http://www.wikidata.org/entity/Q123577'), ('objName', 'US Open')]
#[('obj', 'http://www.wikidata.org/entity/Q41520'), ('objName', 'Wimbledon Championships')]
#[('obj', 'http://www.wikidata.org/entity/Q60874'), ('objName', 'Australian Open')]


queryString = """

PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
SELECT DISTINCT ?countryForSport ?countryForSportName
WHERE {
    # All four tourmamets in Grand Slam
   VALUES (?tournament){
       (wd:Q43605)
       (wd:Q123577)
       (wd:Q41520)
       (wd:Q60874)
   }
   # ?yearlyTournament wdt:P31 ?tournament;
                    wdt:P527 ?subTournament.
   # ?subTournament wdt:P1346 ?winner;
                   wdt:P2094 ?competitionClass.
   
   # ?winner wdt:P1532 ?countryForSport.
   
   # get the label 
   # ?tournament sc:name ?tournamentName .
   # ?yearlyTournament sc:name ?yearlyTournamentName .
   # ?subTournament sc:name ?subTournamentName.
   # ?winner sc:name ?winnerName.
   # ?competitionClass sc:name ?competitionClassName.
   
   # ?countryForSport sc:name ?countryForSportName
   
   BIND(xsd:integer(SUBSTR(?yearlyTournamentName,0,4)) as ?year)
}
GROUP BY ?winner ?winnerName ?countryForSport ?countryForSportName ?competitionClassName ?year
HAVING (count(*) >=4)
ORDER BY DESC (?year)
LIMIT 20

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('countryForSport', 'http://www.wikidata.org/entity/Q183'), ('countryForSportName', 'Germany')]
# 1

# %% [markdown]
# #### SOL 1: all tournaments in the same year, a player is considere if and only if he/she wins in the same category/competitionClass

# %%
# write your final query
# Consider the country for sport property of the tennis player (NO Country of citizenship). 
# Return the countries with at least one player who won at least one edition of each Grand Slam (the result set must be a list of country IRI and label).


# P31 ('instance of')
# P527 ('has part')
# P1346 ('winner')
# P1532 ('country for sport')


queryString = """

PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
SELECT DISTINCT ?countryForSport ?countryForSportName
WHERE {
    # All four tourmamets in Grand Slam
   VALUES (?tournament){
       (wd:Q43605)  # French Open
       (wd:Q123577) # US Open
       (wd:Q41520)  # Wimbledon Championships
       (wd:Q60874)  # Australian Open
   }
   # ?yearlyTournament wdt:P31 ?tournament;
                    wdt:P527 ?subTournament.
   # ?subTournament wdt:P1346 ?winner;
                   wdt:P2094 ?competitionClass.
   
   # ?winner wdt:P1532 ?countryForSport.
   
   # get the label 
   # ?yearlyTournament sc:name ?yearlyTournamentName .
   # ?countryForSport sc:name ?countryForSportName.
   
   BIND(xsd:integer(SUBSTR(?yearlyTournamentName,0,4)) as ?year)
}
GROUP BY ?winner ?countryForSport ?countryForSportName ?competitionClass ?year
HAVING (count(*) >=4)
ORDER BY DESC (?year)
LIMIT 20

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('countryForSport', 'http://www.wikidata.org/entity/Q183'), ('countryForSportName', 'Germany')]
# 1

# %% [markdown]
# #### Another interpretation of: Return the countries with at least one player who won at least one edition of each Grand Slam (SOL 2)

# %%
# write your queries
# Consider the country for sport property of the tennis player (NO Country of citizenship). 
# Return the countries with at least one player who won at least one edition of each Grand Slam (the result set must be a list of country IRI and label).

# P31 ('instance of')
# P527 ('has part')
# P1346 ('winner')
# P1532 ('country for sport')

# REMOVED ?year

queryString = """

PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
SELECT DISTINCT ?winner ?winnerName ?competitionClassName (COUNT(*) as ?tot) #?year ?countryForSport
WHERE {
   # All four tourmamets in Grand Slam
   VALUES (?tournament){
       (wd:Q43605)  # French Open
       (wd:Q123577) # US Open
       (wd:Q41520)  # Wimbledon Championships
       (wd:Q60874)  # Australian Open
   }
   # ?yearlyTournament wdt:P31 ?tournament.
   # ?yearlyTournament wdt:P527 ?subTournament.
   # ?subTournament wdt:P1346 ?winner;
                   wdt:P2094 ?competitionClass.
   
   # ?winner wdt:P1532 ?countryForSport.
   
   # get the label 
   # ?tournament sc:name ?tournamentName .
   # ?yearlyTournament sc:name ?yearlyTournamentName .
   # ?subTournament sc:name ?subTournamentName.
   # ?winner sc:name ?winnerName.
   # ?competitionClass sc:name ?competitionClassName.
   
   #BIND(xsd:integer(SUBSTR(?yearlyTournamentName,0,4)) as ?year)
}
GROUP BY ?winner ?winnerName ?competitionClassName #?countryForSport  ?year
HAVING (count(*) >=4)
#ORDER BY DESC (?year)
LIMIT 100

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('winner', 'http://www.wikidata.org/entity/Q104506'), ('winnerName', 'Björn Borg'), ('competitionClassName', "men's singles"), ('tot', '9')]
# [('winner', 'http://www.wikidata.org/entity/Q16224602'), ('winnerName', 'Yui Kamiji'), ('competitionClassName', "wheelchair tennis women's singles"), ('tot', '6')]
# [('winner', 'http://www.wikidata.org/entity/Q14286'), ('winnerName', 'Chris Evert'), ('competitionClassName', "women's singles"), ('tot', '13')]
# [('winner', 'http://www.wikidata.org/entity/Q312554'), ('winnerName', 'Mahesh Bhupathi'), ('competitionClassName', 'mixed doubles'), ('tot', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q240695'), ('winnerName', 'Larisa Neiland'), ('competitionClassName', 'mixed doubles'), ('tot', '8')]
# [('winner', 'http://www.wikidata.org/entity/Q54654'), ('winnerName', 'Pam Shriver'), ('competitionClassName', "women's doubles"), ('tot', '15')]
# [('winner', 'http://www.wikidata.org/entity/Q232566'), ('winnerName', 'Hsieh Su-wei'), ('competitionClassName', "women's doubles"), ('tot', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q221454'), ('winnerName', 'René Lacoste'), ('competitionClassName', "men's singles"), ('tot', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q1426'), ('winnerName', 'Roger Federer'), ('competitionClassName', "men's singles"), ('tot', '17')]
# [('winner', 'http://www.wikidata.org/entity/Q54537'), ('winnerName', 'Bethanie Mattek-Sands'), ('competitionClassName', "women's doubles"), ('tot', '5')]
# [('winner', 'http://www.wikidata.org/entity/Q11662'), ('winnerName', 'Steffi Graf'), ('competitionClassName', "women's singles"), ('tot', '20')]
# [('winner', 'http://www.wikidata.org/entity/Q264493'), ('winnerName', 'Kathy Jordan'), ('competitionClassName', "women's doubles"), ('tot', '5')]
# [('winner', 'http://www.wikidata.org/entity/Q76334'), ('winnerName', 'Boris Becker'), ('competitionClassName', "men's singles"), ('tot', '5')]
# [('winner', 'http://www.wikidata.org/entity/Q259282'), ('winnerName', 'Betty Stöve'), ('competitionClassName', "women's doubles"), ('tot', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q188080'), ('winnerName', 'Arantxa Sánchez Vicario'), ('competitionClassName', 'mixed doubles'), ('tot', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q173633'), ('winnerName', 'Monica Seles'), ('competitionClassName', "women's singles"), ('tot', '16')]
# [('winner', 'http://www.wikidata.org/entity/Q17466583'), ('winnerName', 'Naomi Osaka'), ('competitionClassName', "women's singles"), ('tot', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q242959'), ('winnerName', 'Kristina Mladenovic'), ('competitionClassName', "women's doubles"), ('tot', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q270414'), ('winnerName', 'Anne Smith'), ('competitionClassName', 'mixed doubles'), ('tot', '5')]
# [('winner', 'http://www.wikidata.org/entity/Q54543'), ('winnerName', 'Helen Wills'), ('competitionClassName', "women's singles"), ('tot', '7')]
# [('winner', 'http://www.wikidata.org/entity/Q298542'), ('winnerName', 'Daniel Nestor'), ('competitionClassName', "men's doubles"), ('tot', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q298542'), ('winnerName', 'Daniel Nestor'), ('competitionClassName', 'mixed doubles'), ('tot', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q229121'), ('winnerName', 'Jana Novotná'), ('competitionClassName', 'mixed doubles'), ('tot', '8')]
# [('winner', 'http://www.wikidata.org/entity/Q54545'), ('winnerName', 'Martina Navratilova'), ('competitionClassName', "women's doubles"), ('tot', '69')]
# [('winner', 'http://www.wikidata.org/entity/Q134720'), ('winnerName', 'Martina Hingis'), ('competitionClassName', "women's singles"), ('tot', '5')]
# [('winner', 'http://www.wikidata.org/entity/Q11459'), ('winnerName', 'Serena Williams'), ('competitionClassName', "women's singles"), ('tot', '21')]
# [('winner', 'http://www.wikidata.org/entity/Q233247'), ('winnerName', 'Maria Bueno'), ('competitionClassName', "women's doubles"), ('tot', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q365139'), ('winnerName', 'William Renshaw'), ('competitionClassName', "men's singles"), ('tot', '6')]
# [('winner', 'http://www.wikidata.org/entity/Q11578'), ('winnerName', 'Venus Williams'), ('competitionClassName', "women's doubles"), ('tot', '11')]
# [('winner', 'http://www.wikidata.org/entity/Q53338'), ('winnerName', 'Louise Brough'), ('competitionClassName', "women's singles"), ('tot', '5')]
# [('winner', 'http://www.wikidata.org/entity/Q455136'), ('winnerName', 'Anders Järryd'), ('competitionClassName', "men's doubles"), ('tot', '7')]
# [('winner', 'http://www.wikidata.org/entity/Q240695'), ('winnerName', 'Larisa Neiland'), ('competitionClassName', "women's doubles"), ('tot', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q229151'), ('winnerName', 'Helena Suková'), ('competitionClassName', 'mixed doubles'), ('tot', '5')]
# [('winner', 'http://www.wikidata.org/entity/Q105550'), ('winnerName', 'Rod Laver'), ('competitionClassName', "men's singles"), ('tot', '7')]
# [('winner', 'http://www.wikidata.org/entity/Q134720'), ('winnerName', 'Martina Hingis'), ('competitionClassName', 'mixed doubles'), ('tot', '7')]
# [('winner', 'http://www.wikidata.org/entity/Q11578'), ('winnerName', 'Venus Williams'), ('competitionClassName', "women's singles"), ('tot', '6')]
# [('winner', 'http://www.wikidata.org/entity/Q16474'), ('winnerName', 'John McEnroe'), ('competitionClassName', "men's doubles"), ('tot', '6')]
# [('winner', 'http://www.wikidata.org/entity/Q54527'), ('winnerName', 'Billie Jean King'), ('competitionClassName', "women's doubles"), ('tot', '5')]
# [('winner', 'http://www.wikidata.org/entity/Q5812'), ('winnerName', 'Novak Djokovic'), ('competitionClassName', "men's singles"), ('tot', '19')]
# [('winner', 'http://www.wikidata.org/entity/Q229005'), ('winnerName', 'Sara Errani'), ('competitionClassName', "women's doubles"), ('tot', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q11459'), ('winnerName', 'Serena Williams'), ('competitionClassName', "women's doubles"), ('tot', '14')]
# [('winner', 'http://www.wikidata.org/entity/Q729789'), ('winnerName', 'Peter Fleming'), ('competitionClassName', "men's doubles"), ('tot', '5')]
# [('winner', 'http://www.wikidata.org/entity/Q16475'), ('winnerName', 'Mats Wilander'), ('competitionClassName', "men's singles"), ('tot', '6')]
# [('winner', 'http://www.wikidata.org/entity/Q54545'), ('winnerName', 'Martina Navratilova'), ('competitionClassName', "women's singles"), ('tot', '51')]
# [('winner', 'http://www.wikidata.org/entity/Q53393'), ('winnerName', 'Jimmy Connors'), ('competitionClassName', "men's singles"), ('tot', '6')]
# [('winner', 'http://www.wikidata.org/entity/Q53550'), ('winnerName', 'Althea Gibson'), ('competitionClassName', "women's doubles"), ('tot', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q2093033'), ('winnerName', 'Pierre-Hugues Herbert'), ('competitionClassName', "men's doubles"), ('tot', '5')]
# [('winner', 'http://www.wikidata.org/entity/Q608657'), ('winnerName', 'Ken Flach'), ('competitionClassName', "men's doubles"), ('tot', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q233243'), ('winnerName', 'Natasha Zvereva'), ('competitionClassName', "women's doubles"), ('tot', '14')]
# [('winner', 'http://www.wikidata.org/entity/Q233332'), ('winnerName', 'Gigi Fernández'), ('competitionClassName', "women's doubles"), ('tot', '16')]
# [('winner', 'http://www.wikidata.org/entity/Q16474'), ('winnerName', 'John McEnroe'), ('competitionClassName', "men's singles"), ('tot', '6')]
# [('winner', 'http://www.wikidata.org/entity/Q229121'), ('winnerName', 'Jana Novotná'), ('competitionClassName', "women's doubles"), ('tot', '18')]
# [('winner', 'http://www.wikidata.org/entity/Q53564'), ('winnerName', 'Doris Hart'), ('competitionClassName', "women's singles"), ('tot', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q371971'), ('winnerName', 'Henri Cochet'), ('competitionClassName', "men's singles"), ('tot', '5')]
# [('winner', 'http://www.wikidata.org/entity/Q188080'), ('winnerName', 'Arantxa Sánchez Vicario'), ('competitionClassName', "women's singles"), ('tot', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q310380'), ('winnerName', 'Jonas Björkman'), ('competitionClassName', "men's doubles"), ('tot', '8')]
# [('winner', 'http://www.wikidata.org/entity/Q54527'), ('winnerName', 'Billie Jean King'), ('competitionClassName', "women's singles"), ('tot', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q229093'), ('winnerName', 'Virginia Ruano Pascual'), ('competitionClassName', "women's doubles"), ('tot', '6')]
# [('winner', 'http://www.wikidata.org/entity/Q11682'), ('winnerName', 'Justine Henin'), ('competitionClassName', "women's singles"), ('tot', '5')]
# [('winner', 'http://www.wikidata.org/entity/Q426049'), ('winnerName', 'John Fitzgerald'), ('competitionClassName', "men's doubles"), ('tot', '7')]
# [('winner', 'http://www.wikidata.org/entity/Q239765'), ('winnerName', 'Tímea Babos'), ('competitionClassName', "women's doubles"), ('tot', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q188080'), ('winnerName', 'Arantxa Sánchez Vicario'), ('competitionClassName', "women's doubles"), ('tot', '5')]
# [('winner', 'http://www.wikidata.org/entity/Q228989'), ('winnerName', 'Lucie Šafářová'), ('competitionClassName', "women's doubles"), ('tot', '5')]
# [('winner', 'http://www.wikidata.org/entity/Q228559'), ('winnerName', 'Evonne Goolagong Cawley'), ('competitionClassName', "women's singles"), ('tot', '5')]
# [('winner', 'http://www.wikidata.org/entity/Q189542'), ('winnerName', 'Stefan Edberg'), ('competitionClassName', "men's singles"), ('tot', '5')]
# [('winner', 'http://www.wikidata.org/entity/Q10132'), ('winnerName', 'Rafael Nadal'), ('competitionClassName', "men's singles"), ('tot', '19')]
# [('winner', 'http://www.wikidata.org/entity/Q182736'), ('winnerName', 'Ivan Lendl'), ('competitionClassName', "men's singles"), ('tot', '16')]
# [('winner', 'http://www.wikidata.org/entity/Q255011'), ('winnerName', 'Hana Mandlíková'), ('competitionClassName', "women's singles"), ('tot', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q11666'), ('winnerName', 'Maria Sharapova'), ('competitionClassName', "women's singles"), ('tot', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q134720'), ('winnerName', 'Martina Hingis'), ('competitionClassName', "women's doubles"), ('tot', '11')]
# [('winner', 'http://www.wikidata.org/entity/Q16224602'), ('winnerName', 'Yui Kamiji'), ('competitionClassName', "wheelchair tennis women's doubles"), ('tot', '5')]
# [('winner', 'http://www.wikidata.org/entity/Q53546'), ('winnerName', 'Zina Garrison'), ('competitionClassName', 'mixed doubles'), ('tot', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q270414'), ('winnerName', 'Anne Smith'), ('competitionClassName', "women's doubles"), ('tot', '5')]
# [('winner', 'http://www.wikidata.org/entity/Q888085'), ('winnerName', 'Bob Lutz'), ('competitionClassName', "men's doubles"), ('tot', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q296282'), ('winnerName', 'Leander Paes'), ('competitionClassName', 'mixed doubles'), ('tot', '9')]
# [('winner', 'http://www.wikidata.org/entity/Q53390'), ('winnerName', 'Maureen Connolly'), ('competitionClassName', "women's singles"), ('tot', '6')]
# [('winner', 'http://www.wikidata.org/entity/Q715130'), ('winnerName', 'Rick Leach'), ('competitionClassName', "men's doubles"), ('tot', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q54545'), ('winnerName', 'Martina Navratilova'), ('competitionClassName', 'mixed doubles'), ('tot', '27')]
# [('winner', 'http://www.wikidata.org/entity/Q715130'), ('winnerName', 'Rick Leach'), ('competitionClassName', 'mixed doubles'), ('tot', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q229151'), ('winnerName', 'Helena Suková'), ('competitionClassName', "women's doubles"), ('tot', '7')]
# [('winner', 'http://www.wikidata.org/entity/Q54537'), ('winnerName', 'Bethanie Mattek-Sands'), ('competitionClassName', 'mixed doubles'), ('tot', '4')]
# 81

# %%
# write your queries
# Consider the country for sport property of the tennis player (NO Country of citizenship). 
# Return the countries with at least one player who won at least one edition of each Grand Slam (the result set must be a list of country IRI and label).

# P31 ('instance of')
# P527 ('has part')
# P1346 ('winner')
# P1532 ('country for sport')

# REMOVED ?year
# COUNTING the wins of winner, who has atleas 4 total wins in his/her whole carrier, GROUPED BY competitionClass

queryString = """

PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
SELECT DISTINCT ?winner ?winnerName ?competitionClassName (COUNT(*) as ?tot) #?year ?countryForSport
WHERE {
   # All four tourmamets in Grand Slam
   VALUES (?tournament){
       (wd:Q43605)  # French Open
       (wd:Q123577) # US Open
       (wd:Q41520)  # Wimbledon Championships
       (wd:Q60874)  # Australian Open
   }
   # ?yearlyTournament wdt:P31 ?tournament.
   # ?yearlyTournament wdt:P527 ?subTournament.
   # ?subTournament wdt:P1346 ?winner;
                   wdt:P2094 ?competitionClass.
   
   # ?winner wdt:P1532 ?countryForSport.
   
   # get the label 
   # ?tournament sc:name ?tournamentName .
   # ?yearlyTournament sc:name ?yearlyTournamentName .
   # ?subTournament sc:name ?subTournamentName.
   # ?winner sc:name ?winnerName.
   # ?competitionClass sc:name ?competitionClassName.
   
   #BIND(xsd:integer(SUBSTR(?yearlyTournamentName,0,4)) as ?year)
}
GROUP BY ?winner ?winnerName ?competitionClassName #?countryForSport  ?year
HAVING (count(*) >=4)
#ORDER BY DESC (?year)
ORDER BY DESC (?winnerName)
LIMIT 100

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('winner', 'http://www.wikidata.org/entity/Q53546'), ('winnerName', 'Zina Garrison'), ('competitionClassName', 'mixed doubles'), ('tot', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q16224602'), ('winnerName', 'Yui Kamiji'), ('competitionClassName', "wheelchair tennis women's singles"), ('tot', '6')]
# [('winner', 'http://www.wikidata.org/entity/Q16224602'), ('winnerName', 'Yui Kamiji'), ('competitionClassName', "wheelchair tennis women's doubles"), ('tot', '5')]
# [('winner', 'http://www.wikidata.org/entity/Q365139'), ('winnerName', 'William Renshaw'), ('competitionClassName', "men's singles"), ('tot', '6')]
# [('winner', 'http://www.wikidata.org/entity/Q229093'), ('winnerName', 'Virginia Ruano Pascual'), ('competitionClassName', "women's doubles"), ('tot', '6')]
# [('winner', 'http://www.wikidata.org/entity/Q11578'), ('winnerName', 'Venus Williams'), ('competitionClassName', "women's doubles"), ('tot', '11')]
# [('winner', 'http://www.wikidata.org/entity/Q11578'), ('winnerName', 'Venus Williams'), ('competitionClassName', "women's singles"), ('tot', '6')]
# [('winner', 'http://www.wikidata.org/entity/Q239765'), ('winnerName', 'Tímea Babos'), ('competitionClassName', "women's doubles"), ('tot', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q11662'), ('winnerName', 'Steffi Graf'), ('competitionClassName', "women's singles"), ('tot', '20')]
# [('winner', 'http://www.wikidata.org/entity/Q189542'), ('winnerName', 'Stefan Edberg'), ('competitionClassName', "men's singles"), ('tot', '5')]
# [('winner', 'http://www.wikidata.org/entity/Q11459'), ('winnerName', 'Serena Williams'), ('competitionClassName', "women's singles"), ('tot', '21')]
# [('winner', 'http://www.wikidata.org/entity/Q11459'), ('winnerName', 'Serena Williams'), ('competitionClassName', "women's doubles"), ('tot', '14')]
# [('winner', 'http://www.wikidata.org/entity/Q229005'), ('winnerName', 'Sara Errani'), ('competitionClassName', "women's doubles"), ('tot', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q1426'), ('winnerName', 'Roger Federer'), ('competitionClassName', "men's singles"), ('tot', '17')]
# [('winner', 'http://www.wikidata.org/entity/Q105550'), ('winnerName', 'Rod Laver'), ('competitionClassName', "men's singles"), ('tot', '7')]
# [('winner', 'http://www.wikidata.org/entity/Q715130'), ('winnerName', 'Rick Leach'), ('competitionClassName', "men's doubles"), ('tot', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q715130'), ('winnerName', 'Rick Leach'), ('competitionClassName', 'mixed doubles'), ('tot', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q221454'), ('winnerName', 'René Lacoste'), ('competitionClassName', "men's singles"), ('tot', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q10132'), ('winnerName', 'Rafael Nadal'), ('competitionClassName', "men's singles"), ('tot', '19')]
# [('winner', 'http://www.wikidata.org/entity/Q2093033'), ('winnerName', 'Pierre-Hugues Herbert'), ('competitionClassName', "men's doubles"), ('tot', '5')]
# [('winner', 'http://www.wikidata.org/entity/Q729789'), ('winnerName', 'Peter Fleming'), ('competitionClassName', "men's doubles"), ('tot', '5')]
# [('winner', 'http://www.wikidata.org/entity/Q54654'), ('winnerName', 'Pam Shriver'), ('competitionClassName', "women's doubles"), ('tot', '15')]
# [('winner', 'http://www.wikidata.org/entity/Q5812'), ('winnerName', 'Novak Djokovic'), ('competitionClassName', "men's singles"), ('tot', '19')]
# [('winner', 'http://www.wikidata.org/entity/Q233243'), ('winnerName', 'Natasha Zvereva'), ('competitionClassName', "women's doubles"), ('tot', '14')]
# [('winner', 'http://www.wikidata.org/entity/Q17466583'), ('winnerName', 'Naomi Osaka'), ('competitionClassName', "women's singles"), ('tot', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q173633'), ('winnerName', 'Monica Seles'), ('competitionClassName', "women's singles"), ('tot', '16')]
# [('winner', 'http://www.wikidata.org/entity/Q53390'), ('winnerName', 'Maureen Connolly'), ('competitionClassName', "women's singles"), ('tot', '6')]
# [('winner', 'http://www.wikidata.org/entity/Q16475'), ('winnerName', 'Mats Wilander'), ('competitionClassName', "men's singles"), ('tot', '6')]
# [('winner', 'http://www.wikidata.org/entity/Q54545'), ('winnerName', 'Martina Navratilova'), ('competitionClassName', "women's doubles"), ('tot', '69')]
# [('winner', 'http://www.wikidata.org/entity/Q54545'), ('winnerName', 'Martina Navratilova'), ('competitionClassName', "women's singles"), ('tot', '51')]
# [('winner', 'http://www.wikidata.org/entity/Q54545'), ('winnerName', 'Martina Navratilova'), ('competitionClassName', 'mixed doubles'), ('tot', '27')]
# [('winner', 'http://www.wikidata.org/entity/Q134720'), ('winnerName', 'Martina Hingis'), ('competitionClassName', "women's singles"), ('tot', '5')]
# [('winner', 'http://www.wikidata.org/entity/Q134720'), ('winnerName', 'Martina Hingis'), ('competitionClassName', 'mixed doubles'), ('tot', '7')]
# [('winner', 'http://www.wikidata.org/entity/Q134720'), ('winnerName', 'Martina Hingis'), ('competitionClassName', "women's doubles"), ('tot', '11')]
# [('winner', 'http://www.wikidata.org/entity/Q11666'), ('winnerName', 'Maria Sharapova'), ('competitionClassName', "women's singles"), ('tot', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q233247'), ('winnerName', 'Maria Bueno'), ('competitionClassName', "women's doubles"), ('tot', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q312554'), ('winnerName', 'Mahesh Bhupathi'), ('competitionClassName', 'mixed doubles'), ('tot', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q228989'), ('winnerName', 'Lucie Šafářová'), ('competitionClassName', "women's doubles"), ('tot', '5')]
# [('winner', 'http://www.wikidata.org/entity/Q53338'), ('winnerName', 'Louise Brough'), ('competitionClassName', "women's singles"), ('tot', '5')]
# [('winner', 'http://www.wikidata.org/entity/Q296282'), ('winnerName', 'Leander Paes'), ('competitionClassName', 'mixed doubles'), ('tot', '9')]
# [('winner', 'http://www.wikidata.org/entity/Q240695'), ('winnerName', 'Larisa Neiland'), ('competitionClassName', 'mixed doubles'), ('tot', '8')]
# [('winner', 'http://www.wikidata.org/entity/Q240695'), ('winnerName', 'Larisa Neiland'), ('competitionClassName', "women's doubles"), ('tot', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q242959'), ('winnerName', 'Kristina Mladenovic'), ('competitionClassName', "women's doubles"), ('tot', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q608657'), ('winnerName', 'Ken Flach'), ('competitionClassName', "men's doubles"), ('tot', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q264493'), ('winnerName', 'Kathy Jordan'), ('competitionClassName', "women's doubles"), ('tot', '5')]
# [('winner', 'http://www.wikidata.org/entity/Q11682'), ('winnerName', 'Justine Henin'), ('competitionClassName', "women's singles"), ('tot', '5')]
# [('winner', 'http://www.wikidata.org/entity/Q310380'), ('winnerName', 'Jonas Björkman'), ('competitionClassName', "men's doubles"), ('tot', '8')]
# [('winner', 'http://www.wikidata.org/entity/Q16474'), ('winnerName', 'John McEnroe'), ('competitionClassName', "men's doubles"), ('tot', '6')]
# [('winner', 'http://www.wikidata.org/entity/Q16474'), ('winnerName', 'John McEnroe'), ('competitionClassName', "men's singles"), ('tot', '6')]
# [('winner', 'http://www.wikidata.org/entity/Q426049'), ('winnerName', 'John Fitzgerald'), ('competitionClassName', "men's doubles"), ('tot', '7')]
# [('winner', 'http://www.wikidata.org/entity/Q53393'), ('winnerName', 'Jimmy Connors'), ('competitionClassName', "men's singles"), ('tot', '6')]
# [('winner', 'http://www.wikidata.org/entity/Q229121'), ('winnerName', 'Jana Novotná'), ('competitionClassName', 'mixed doubles'), ('tot', '8')]
# [('winner', 'http://www.wikidata.org/entity/Q229121'), ('winnerName', 'Jana Novotná'), ('competitionClassName', "women's doubles"), ('tot', '18')]
# [('winner', 'http://www.wikidata.org/entity/Q182736'), ('winnerName', 'Ivan Lendl'), ('competitionClassName', "men's singles"), ('tot', '16')]
# [('winner', 'http://www.wikidata.org/entity/Q232566'), ('winnerName', 'Hsieh Su-wei'), ('competitionClassName', "women's doubles"), ('tot', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q371971'), ('winnerName', 'Henri Cochet'), ('competitionClassName', "men's singles"), ('tot', '5')]
# [('winner', 'http://www.wikidata.org/entity/Q229151'), ('winnerName', 'Helena Suková'), ('competitionClassName', 'mixed doubles'), ('tot', '5')]
# [('winner', 'http://www.wikidata.org/entity/Q229151'), ('winnerName', 'Helena Suková'), ('competitionClassName', "women's doubles"), ('tot', '7')]
# [('winner', 'http://www.wikidata.org/entity/Q54543'), ('winnerName', 'Helen Wills'), ('competitionClassName', "women's singles"), ('tot', '7')]
# [('winner', 'http://www.wikidata.org/entity/Q255011'), ('winnerName', 'Hana Mandlíková'), ('competitionClassName', "women's singles"), ('tot', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q233332'), ('winnerName', 'Gigi Fernández'), ('competitionClassName', "women's doubles"), ('tot', '16')]
# [('winner', 'http://www.wikidata.org/entity/Q228559'), ('winnerName', 'Evonne Goolagong Cawley'), ('competitionClassName', "women's singles"), ('tot', '5')]
# [('winner', 'http://www.wikidata.org/entity/Q53564'), ('winnerName', 'Doris Hart'), ('competitionClassName', "women's singles"), ('tot', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q298542'), ('winnerName', 'Daniel Nestor'), ('competitionClassName', "men's doubles"), ('tot', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q298542'), ('winnerName', 'Daniel Nestor'), ('competitionClassName', 'mixed doubles'), ('tot', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q14286'), ('winnerName', 'Chris Evert'), ('competitionClassName', "women's singles"), ('tot', '13')]
# [('winner', 'http://www.wikidata.org/entity/Q76334'), ('winnerName', 'Boris Becker'), ('competitionClassName', "men's singles"), ('tot', '5')]
# [('winner', 'http://www.wikidata.org/entity/Q888085'), ('winnerName', 'Bob Lutz'), ('competitionClassName', "men's doubles"), ('tot', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q104506'), ('winnerName', 'Björn Borg'), ('competitionClassName', "men's singles"), ('tot', '9')]
# [('winner', 'http://www.wikidata.org/entity/Q54527'), ('winnerName', 'Billie Jean King'), ('competitionClassName', "women's doubles"), ('tot', '5')]
# [('winner', 'http://www.wikidata.org/entity/Q54527'), ('winnerName', 'Billie Jean King'), ('competitionClassName', "women's singles"), ('tot', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q259282'), ('winnerName', 'Betty Stöve'), ('competitionClassName', "women's doubles"), ('tot', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q54537'), ('winnerName', 'Bethanie Mattek-Sands'), ('competitionClassName', "women's doubles"), ('tot', '5')]
# [('winner', 'http://www.wikidata.org/entity/Q54537'), ('winnerName', 'Bethanie Mattek-Sands'), ('competitionClassName', 'mixed doubles'), ('tot', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q188080'), ('winnerName', 'Arantxa Sánchez Vicario'), ('competitionClassName', 'mixed doubles'), ('tot', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q188080'), ('winnerName', 'Arantxa Sánchez Vicario'), ('competitionClassName', "women's singles"), ('tot', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q188080'), ('winnerName', 'Arantxa Sánchez Vicario'), ('competitionClassName', "women's doubles"), ('tot', '5')]
# [('winner', 'http://www.wikidata.org/entity/Q270414'), ('winnerName', 'Anne Smith'), ('competitionClassName', 'mixed doubles'), ('tot', '5')]
# [('winner', 'http://www.wikidata.org/entity/Q270414'), ('winnerName', 'Anne Smith'), ('competitionClassName', "women's doubles"), ('tot', '5')]
# [('winner', 'http://www.wikidata.org/entity/Q455136'), ('winnerName', 'Anders Järryd'), ('competitionClassName', "men's doubles"), ('tot', '7')]
# [('winner', 'http://www.wikidata.org/entity/Q53550'), ('winnerName', 'Althea Gibson'), ('competitionClassName', "women's doubles"), ('tot', '4')]
# 81

# %%
# write your queries
# Consider the country for sport property of the tennis player (NO Country of citizenship). 
# Return the countries with at least one player who won at least one edition of each Grand Slam (the result set must be a list of country IRI and label).

# P31 ('instance of')
# P527 ('has part')
# P1346 ('winner')
# P1532 ('country for sport')

# REMOVED ?year
# COUNTING the wins of winner, who has atleas 4 total wins in his/her whole carrier, 
# REMOVING GROUPED by to check in depth if the results are correct

queryString = """

PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
SELECT DISTINCT ?winner ?winnerName ?competitionClassName ?subTournamentName #(COUNT(*) as ?tot) #?year ?countryForSport
WHERE {
   # All four tourmamets in Grand Slam
   VALUES (?tournament){
       (wd:Q43605)  # French Open
       (wd:Q123577) # US Open
       (wd:Q41520)  # Wimbledon Championships
       (wd:Q60874)  # Australian Open
   }
   # ?yearlyTournament wdt:P31 ?tournament.
   # ?yearlyTournament wdt:P527 ?subTournament.
   # ?subTournament wdt:P1346 ?winner;
                   wdt:P2094 ?competitionClass.
   
   # ?winner wdt:P1532 ?countryForSport.
   
   # get the label 
   # ?tournament sc:name ?tournamentName .
   # ?yearlyTournament sc:name ?yearlyTournamentName .
   # ?subTournament sc:name ?subTournamentName.
   # ?winner sc:name ?winnerName.
   # ?competitionClass sc:name ?competitionClassName.
   
   #BIND(xsd:integer(SUBSTR(?yearlyTournamentName,0,4)) as ?year)
}
#GROUP BY ?winner ?winnerName ?competitionClassName #?countryForSport  ?year
#HAVING (count(*) >=4)
#ORDER BY DESC (?year)
ORDER BY DESC (?winnerName)
LIMIT 20

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('winner', 'http://www.wikidata.org/entity/Q345626'), ('winnerName', 'Łukasz Kubot'), ('competitionClassName', "men's doubles"), ('subTournamentName', "2014 Australian Open – Men's Doubles")]
# [('winner', 'http://www.wikidata.org/entity/Q345626'), ('winnerName', 'Łukasz Kubot'), ('competitionClassName', "men's doubles"), ('subTournamentName', "2017 Wimbledon Championships – Men's Doubles")]
# [('winner', 'http://www.wikidata.org/entity/Q8080164'), ('winnerName', 'İpek Soylu'), ('competitionClassName', "girls' doubles"), ('subTournamentName', "2014 US Open – Girls' Doubles")]
# [('winner', 'http://www.wikidata.org/entity/Q227389'), ('winnerName', 'Zsuzsa Körmöczy'), ('competitionClassName', "women's singles"), ('subTournamentName', "1958 French Championships – Women's Singles")]
# [('winner', 'http://www.wikidata.org/entity/Q53546'), ('winnerName', 'Zina Garrison'), ('competitionClassName', 'mixed doubles'), ('subTournamentName', '1988 Wimbledon Championships – Mixed Doubles')]
# [('winner', 'http://www.wikidata.org/entity/Q53546'), ('winnerName', 'Zina Garrison'), ('competitionClassName', 'mixed doubles'), ('subTournamentName', '1991 Wimbledon Championships – Mixed Doubles')]
# [('winner', 'http://www.wikidata.org/entity/Q53546'), ('winnerName', 'Zina Garrison'), ('competitionClassName', 'mixed doubles'), ('subTournamentName', '1990 Wimbledon Championships – Mixed Doubles')]
# [('winner', 'http://www.wikidata.org/entity/Q53546'), ('winnerName', 'Zina Garrison'), ('competitionClassName', 'mixed doubles'), ('subTournamentName', '1987 Australian Open – Mixed Doubles')]
# [('winner', 'http://www.wikidata.org/entity/Q197639'), ('winnerName', 'Zheng Jie'), ('competitionClassName', "women's doubles"), ('subTournamentName', "2006 Australian Open – Women's Doubles")]
# [('winner', 'http://www.wikidata.org/entity/Q197639'), ('winnerName', 'Zheng Jie'), ('competitionClassName', "women's doubles"), ('subTournamentName', "2006 Wimbledon Championships – Women's Doubles")]
# [('winner', 'http://www.wikidata.org/entity/Q197291'), ('winnerName', 'Zhang Shuai'), ('competitionClassName', "women's doubles"), ('subTournamentName', "2019 Australian Open – Women's Doubles")]
# [('winner', 'http://www.wikidata.org/entity/Q957935'), ('winnerName', 'Yvon Petra'), ('competitionClassName', "men's singles"), ('subTournamentName', "1946 Wimbledon Championships – Men's Singles")]
# [('winner', 'http://www.wikidata.org/entity/Q1391241'), ('winnerName', 'Yuki Bhambri'), ('competitionClassName', "boys' singles"), ('subTournamentName', "2009 Australian Open – Boys' Singles")]
# [('winner', 'http://www.wikidata.org/entity/Q16224602'), ('winnerName', 'Yui Kamiji'), ('competitionClassName', "wheelchair tennis women's singles"), ('subTournamentName', "2017 Australian Open – Wheelchair Women's Singles")]
# [('winner', 'http://www.wikidata.org/entity/Q16224602'), ('winnerName', 'Yui Kamiji'), ('competitionClassName', "wheelchair tennis women's doubles"), ('subTournamentName', "2018 Wimbledon Championships – Wheelchair Women's Doubles")]
# [('winner', 'http://www.wikidata.org/entity/Q16224602'), ('winnerName', 'Yui Kamiji'), ('competitionClassName', "wheelchair tennis women's singles"), ('subTournamentName', "2017 French Open – Wheelchair Women's Singles")]
# [('winner', 'http://www.wikidata.org/entity/Q16224602'), ('winnerName', 'Yui Kamiji'), ('competitionClassName', "wheelchair tennis women's doubles"), ('subTournamentName', "2017 French Open – Wheelchair Women's Doubles")]
# [('winner', 'http://www.wikidata.org/entity/Q16224602'), ('winnerName', 'Yui Kamiji'), ('competitionClassName', "wheelchair tennis women's singles"), ('subTournamentName', "2017 US Open – Wheelchair Women's Singles")]
# [('winner', 'http://www.wikidata.org/entity/Q16224602'), ('winnerName', 'Yui Kamiji'), ('competitionClassName', "wheelchair tennis women's doubles"), ('subTournamentName', "2021 Wimbledon Championships – Wheelchair Women's Doubles")]
# [('winner', 'http://www.wikidata.org/entity/Q16224602'), ('winnerName', 'Yui Kamiji'), ('competitionClassName', "wheelchair tennis women's singles"), ('subTournamentName', "2018 French Open – Wheelchair Women's Singles")]
# 20

# %%
# write your queries
# Consider the country for sport property of the tennis player (NO Country of citizenship). 
# Return the countries with at least one player who won at least one edition of each Grand Slam (the result set must be a list of country IRI and label).

# P31 ('instance of')
# P527 ('has part')
# P1346 ('winner')
# P1532 ('country for sport')

# REMOVED ?year
# COUNTING the wins of winner, who has atleas 4 total wins in his/her whole carrier, 
# REMOVING GROUPED by to check in depth if the results are correct


queryString = """

PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
SELECT DISTINCT ?winner ?winnerName ?competitionClassName ?yearlyTournamentName ?subTournamentName #(COUNT(*) as ?tot) #?year ?countryForSport
WHERE {
   # All four tourmamets in Grand Slam
   VALUES (?tournament){
       (wd:Q43605)  # French Open
       (wd:Q123577) # US Open
       (wd:Q41520)  # Wimbledon Championships
       (wd:Q60874)  # Australian Open
   }
   # ?yearlyTournament wdt:P31 ?tournament.
   # ?yearlyTournament wdt:P527 ?subTournament.
   # ?subTournament wdt:P1346 ?winner;
                   wdt:P2094 ?competitionClass.
   
   # ?winner wdt:P1532 ?countryForSport.
   
   # get the label 
   # ?tournament sc:name ?tournamentName .
   # ?yearlyTournament sc:name ?yearlyTournamentName .
   # ?subTournament sc:name ?subTournamentName.
   # ?winner sc:name ?winnerName.
   # ?competitionClass sc:name ?competitionClassName.
   
   #BIND(xsd:integer(SUBSTR(?yearlyTournamentName,0,4)) as ?year)
   #BIND(SUBSTR(?yearlyTournamentName,0,4)) as ?year)
}
#GROUP BY ?winner ?winnerName ?competitionClassName #?countryForSport  ?year
#HAVING (count(*) >=4)
#ORDER BY DESC (?year)
ORDER BY DESC (?winnerName)
LIMIT 20

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('winner', 'http://www.wikidata.org/entity/Q345626'), ('winnerName', 'Łukasz Kubot'), ('competitionClassName', "men's doubles"), ('yearlyTournamentName', '2014 Australian Open'), ('subTournamentName', "2014 Australian Open – Men's Doubles")]
# [('winner', 'http://www.wikidata.org/entity/Q345626'), ('winnerName', 'Łukasz Kubot'), ('competitionClassName', "men's doubles"), ('yearlyTournamentName', '2017 Wimbledon Championships'), ('subTournamentName', "2017 Wimbledon Championships – Men's Doubles")]
# [('winner', 'http://www.wikidata.org/entity/Q8080164'), ('winnerName', 'İpek Soylu'), ('competitionClassName', "girls' doubles"), ('yearlyTournamentName', '2014 US Open'), ('subTournamentName', "2014 US Open – Girls' Doubles")]
# [('winner', 'http://www.wikidata.org/entity/Q227389'), ('winnerName', 'Zsuzsa Körmöczy'), ('competitionClassName', "women's singles"), ('yearlyTournamentName', '1958 French Championships'), ('subTournamentName', "1958 French Championships – Women's Singles")]
# [('winner', 'http://www.wikidata.org/entity/Q53546'), ('winnerName', 'Zina Garrison'), ('competitionClassName', 'mixed doubles'), ('yearlyTournamentName', '1988 Wimbledon Championships'), ('subTournamentName', '1988 Wimbledon Championships – Mixed Doubles')]
# [('winner', 'http://www.wikidata.org/entity/Q53546'), ('winnerName', 'Zina Garrison'), ('competitionClassName', 'mixed doubles'), ('yearlyTournamentName', '1991 Wimbledon Championships'), ('subTournamentName', '1991 Wimbledon Championships – Mixed Doubles')]
# [('winner', 'http://www.wikidata.org/entity/Q53546'), ('winnerName', 'Zina Garrison'), ('competitionClassName', 'mixed doubles'), ('yearlyTournamentName', '1990 Wimbledon Championships'), ('subTournamentName', '1990 Wimbledon Championships – Mixed Doubles')]
# [('winner', 'http://www.wikidata.org/entity/Q53546'), ('winnerName', 'Zina Garrison'), ('competitionClassName', 'mixed doubles'), ('yearlyTournamentName', '1987 Australian Open'), ('subTournamentName', '1987 Australian Open – Mixed Doubles')]
# [('winner', 'http://www.wikidata.org/entity/Q197639'), ('winnerName', 'Zheng Jie'), ('competitionClassName', "women's doubles"), ('yearlyTournamentName', '2006 Australian Open'), ('subTournamentName', "2006 Australian Open – Women's Doubles")]
# [('winner', 'http://www.wikidata.org/entity/Q197639'), ('winnerName', 'Zheng Jie'), ('competitionClassName', "women's doubles"), ('yearlyTournamentName', '2006 Wimbledon Championships'), ('subTournamentName', "2006 Wimbledon Championships – Women's Doubles")]
# [('winner', 'http://www.wikidata.org/entity/Q197291'), ('winnerName', 'Zhang Shuai'), ('competitionClassName', "women's doubles"), ('yearlyTournamentName', '2019 Australian Open'), ('subTournamentName', "2019 Australian Open – Women's Doubles")]
# [('winner', 'http://www.wikidata.org/entity/Q957935'), ('winnerName', 'Yvon Petra'), ('competitionClassName', "men's singles"), ('yearlyTournamentName', '1946 Wimbledon Championships'), ('subTournamentName', "1946 Wimbledon Championships – Men's Singles")]
# [('winner', 'http://www.wikidata.org/entity/Q1391241'), ('winnerName', 'Yuki Bhambri'), ('competitionClassName', "boys' singles"), ('yearlyTournamentName', '2009 Australian Open'), ('subTournamentName', "2009 Australian Open – Boys' Singles")]
# [('winner', 'http://www.wikidata.org/entity/Q16224602'), ('winnerName', 'Yui Kamiji'), ('competitionClassName', "wheelchair tennis women's singles"), ('yearlyTournamentName', '2017 Australian Open'), ('subTournamentName', "2017 Australian Open – Wheelchair Women's Singles")]
# [('winner', 'http://www.wikidata.org/entity/Q16224602'), ('winnerName', 'Yui Kamiji'), ('competitionClassName', "wheelchair tennis women's doubles"), ('yearlyTournamentName', '2018 Wimbledon Championships'), ('subTournamentName', "2018 Wimbledon Championships – Wheelchair Women's Doubles")]
# [('winner', 'http://www.wikidata.org/entity/Q16224602'), ('winnerName', 'Yui Kamiji'), ('competitionClassName', "wheelchair tennis women's doubles"), ('yearlyTournamentName', '2017 French Open'), ('subTournamentName', "2017 French Open – Wheelchair Women's Doubles")]
# [('winner', 'http://www.wikidata.org/entity/Q16224602'), ('winnerName', 'Yui Kamiji'), ('competitionClassName', "wheelchair tennis women's singles"), ('yearlyTournamentName', '2017 French Open'), ('subTournamentName', "2017 French Open – Wheelchair Women's Singles")]
# [('winner', 'http://www.wikidata.org/entity/Q16224602'), ('winnerName', 'Yui Kamiji'), ('competitionClassName', "wheelchair tennis women's singles"), ('yearlyTournamentName', '2017 US Open'), ('subTournamentName', "2017 US Open – Wheelchair Women's Singles")]
# [('winner', 'http://www.wikidata.org/entity/Q16224602'), ('winnerName', 'Yui Kamiji'), ('competitionClassName', "wheelchair tennis women's doubles"), ('yearlyTournamentName', '2021 Wimbledon Championships'), ('subTournamentName', "2021 Wimbledon Championships – Wheelchair Women's Doubles")]
# [('winner', 'http://www.wikidata.org/entity/Q16224602'), ('winnerName', 'Yui Kamiji'), ('competitionClassName', "wheelchair tennis women's singles"), ('yearlyTournamentName', '2018 French Open'), ('subTournamentName', "2018 French Open – Wheelchair Women's Singles")]
# 20

# %%
# write your queries
# Consider the country for sport property of the tennis player (NO Country of citizenship). 
# Return the countries with at least one player who won at least one edition of each Grand Slam (the result set must be a list of country IRI and label).

# P31 ('instance of')
# P527 ('has part')
# P1346 ('winner')
# P1532 ('country for sport')

# FINDING shor way to GROUP something above yearlyTournament 


queryString = """

PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
SELECT DISTINCT ?p ?pName #(COUNT(*) as ?tot) #?year ?countryForSport
WHERE {
   # All four tourmamets in Grand Slam
   VALUES (?tournament){
       (wd:Q43605)  # French Open
       (wd:Q123577) # US Open
       (wd:Q41520)  # Wimbledon Championships
       (wd:Q60874)  # Australian Open
   }
   # ?yearlyTournament wdt:P31 ?tournament.
   # ?yearlyTournament ?p ?o.
   #?subTournament wdt:P1346 ?winner;
   #                wdt:P2094 ?competitionClass.
   
   #?winner wdt:P1532 ?countryForSport.
   
   # get the label 
   # ?tournament sc:name ?tournamentName .
   # ?yearlyTournament sc:name ?yearlyTournamentName .
   # ?p sc:name ?pName.
   #?o sc:name ?oName.
   #?subTournament sc:name ?subTournamentName.
   #?winner sc:name ?winnerName.
   #?competitionClass sc:name ?competitionClassName.
   
   #BIND(xsd:integer(SUBSTR(?yearlyTournamentName,0,4)) as ?year)
   #BIND(SUBSTR(?yearlyTournamentName,0,4)) as ?year)
}
#GROUP BY ?winner ?winnerName ?competitionClassName #?countryForSport  ?year
#HAVING (count(*) >=4)
#ORDER BY DESC (?year)
#ORDER BY DESC (?winnerName)
#ORDER BY DESC (?winnerName)
LIMIT 20

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P6880'), ('pName', 'ATP tennis tournament edition ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1132'), ('pName', 'number of participants')]
# [('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity')]
# [('p', 'http://www.wikidata.org/prop/direct/P155'), ('pName', 'follows')]
# [('p', 'http://www.wikidata.org/prop/direct/P156'), ('pName', 'followed by')]
# [('p', 'http://www.wikidata.org/prop/direct/P17'), ('pName', 'country')]
# [('p', 'http://www.wikidata.org/prop/direct/P18'), ('pName', 'image')]
# [('p', 'http://www.wikidata.org/prop/direct/P2094'), ('pName', 'competition class')]
# [('p', 'http://www.wikidata.org/prop/direct/P214'), ('pName', 'VIAF ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P227'), ('pName', 'GND ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2581'), ('pName', 'BabelNet ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2671'), ('pName', 'Google Knowledge Graph ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P276'), ('pName', 'location')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('p', 'http://www.wikidata.org/prop/direct/P3417'), ('pName', 'Quora topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P361'), ('pName', 'part of')]
# [('p', 'http://www.wikidata.org/prop/direct/P373'), ('pName', 'Commons category')]
# [('p', 'http://www.wikidata.org/prop/direct/P393'), ('pName', 'edition number')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part')]
# [('p', 'http://www.wikidata.org/prop/direct/P580'), ('pName', 'start time')]
# 20

# %%
# write your queries
# Consider the country for sport property of the tennis player (NO Country of citizenship). 
# Return the countries with at least one player who won at least one edition of each Grand Slam (the result set must be a list of country IRI and label).

# P31 ('instance of')
# P527 ('has part')
# P1346 ('winner')
# P1532 ('country for sport')

# FINDING shor way to GROUP something above yearlyTournament
# added FILTER


queryString = """

PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
SELECT DISTINCT ?p ?pName ?o ?oName #(COUNT(*) as ?tot) #?year ?countryForSport
WHERE {
   # All four tourmamets in Grand Slam
   VALUES (?tournament){
       (wd:Q43605)  # French Open
       (wd:Q123577) # US Open
       (wd:Q41520)  # Wimbledon Championships
       (wd:Q60874)  # Australian Open
   }
   # ?yearlyTournament wdt:P31 ?tournament.
   # ?yearlyTournament ?p ?o.
   #?subTournament wdt:P1346 ?winner;
   #                wdt:P2094 ?competitionClass.
   
   #?winner wdt:P1532 ?countryForSport.
   
   # get the label 
   # ?tournament sc:name ?tournamentName .
   # ?yearlyTournament sc:name ?yearlyTournamentName .
   # ?p sc:name ?pName.
   # ?o sc:name ?oName.
   #?subTournament sc:name ?subTournamentName.
   #?winner sc:name ?winnerName.
   #?competitionClass sc:name ?competitionClassName.
   
   #BIND(xsd:integer(SUBSTR(?yearlyTournamentName,0,4)) as ?year)
   #BIND(SUBSTR(?yearlyTournamentName,0,4)) as ?year)
   
   FILTER (?p not in (wdt:P155, wdt:P156))
}
#GROUP BY ?winner ?winnerName ?competitionClassName #?countryForSport  ?year
#HAVING (count(*) >=4)
#ORDER BY DESC (?year)
#ORDER BY DESC (?winnerName)
#ORDER BY DESC (?winnerName)
LIMIT 20

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q3130'), ('oName', 'Sydney')]
# [('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q3141'), ('oName', 'Melbourne')]
# [('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q60'), ('oName', 'New York City')]
# [('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q90'), ('oName', 'Paris')]
# [('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q5112'), ('oName', 'Adelaide')]
# [('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q736742'), ('oName', 'Wimbledon')]
# [('p', 'http://www.wikidata.org/prop/direct/P17'), ('pName', 'country'), ('o', 'http://www.wikidata.org/entity/Q142'), ('oName', 'France')]
# [('p', 'http://www.wikidata.org/prop/direct/P17'), ('pName', 'country'), ('o', 'http://www.wikidata.org/entity/Q145'), ('oName', 'United Kingdom')]
# [('p', 'http://www.wikidata.org/prop/direct/P17'), ('pName', 'country'), ('o', 'http://www.wikidata.org/entity/Q174193'), ('oName', 'United Kingdom of Great Britain and Ireland')]
# [('p', 'http://www.wikidata.org/prop/direct/P17'), ('pName', 'country'), ('o', 'http://www.wikidata.org/entity/Q30'), ('oName', 'United States of America')]
# [('p', 'http://www.wikidata.org/prop/direct/P17'), ('pName', 'country'), ('o', 'http://www.wikidata.org/entity/Q408'), ('oName', 'Australia')]
# [('p', 'http://www.wikidata.org/prop/direct/P2094'), ('pName', 'competition class'), ('o', 'http://www.wikidata.org/entity/Q920057'), ('oName', "women's sports")]
# [('p', 'http://www.wikidata.org/prop/direct/P276'), ('pName', 'location'), ('o', 'http://www.wikidata.org/entity/Q1613027'), ('oName', 'Stade Roland-Garros')]
# [('p', 'http://www.wikidata.org/prop/direct/P276'), ('pName', 'location'), ('o', 'http://www.wikidata.org/entity/Q7994559'), ('oName', 'White City Stadium')]
# [('p', 'http://www.wikidata.org/prop/direct/P276'), ('pName', 'location'), ('o', 'http://www.wikidata.org/entity/Q815369'), ('oName', 'All England Lawn Tennis and Croquet Club')]
# [('p', 'http://www.wikidata.org/prop/direct/P276'), ('pName', 'location'), ('o', 'http://www.wikidata.org/entity/Q1852081'), ('oName', 'USTA Billie Jean King National Tennis Center')]
# [('p', 'http://www.wikidata.org/prop/direct/P276'), ('pName', 'location'), ('o', 'http://www.wikidata.org/entity/Q2228393'), ('oName', 'Melbourne Park')]
# [('p', 'http://www.wikidata.org/prop/direct/P276'), ('pName', 'location'), ('o', 'http://www.wikidata.org/entity/Q60'), ('oName', 'New York City')]
# [('p', 'http://www.wikidata.org/prop/direct/P276'), ('pName', 'location'), ('o', 'http://www.wikidata.org/entity/Q84'), ('oName', 'London')]
# [('p', 'http://www.wikidata.org/prop/direct/P276'), ('pName', 'location'), ('o', 'http://www.wikidata.org/entity/Q3387742'), ('oName', 'West Side Tennis Club')]
# 20

# %%
# write your queries
# Consider the country for sport property of the tennis player (NO Country of citizenship). 
# Return the countries with at least one player who won at least one edition of each Grand Slam (the result set must be a list of country IRI and label).

# P31 ('instance of')
# P527 ('has part')
# P1346 ('winner')
# P1532 ('country for sport')

# FINDING shor way to GROUP something above yearlyTournament
# added FILTER and extended LIMIT

queryString = """

PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
SELECT DISTINCT ?p ?pName ?o ?oName #(COUNT(*) as ?tot) #?year ?countryForSport
WHERE {
   # All four tourmamets in Grand Slam
   VALUES (?tournament){
       (wd:Q43605)  # French Open
       (wd:Q123577) # US Open
       (wd:Q41520)  # Wimbledon Championships
       (wd:Q60874)  # Australian Open
   }
   # ?yearlyTournament wdt:P31 ?tournament.
   # ?yearlyTournament ?p ?o.
   #?subTournament wdt:P1346 ?winner;
   #                wdt:P2094 ?competitionClass.
   
   #?winner wdt:P1532 ?countryForSport.
   
   # get the label 
   # ?tournament sc:name ?tournamentName .
   # ?yearlyTournament sc:name ?yearlyTournamentName .
   # ?p sc:name ?pName.
   # ?o sc:name ?oName.
   #?subTournament sc:name ?subTournamentName.
   #?winner sc:name ?winnerName.
   #?competitionClass sc:name ?competitionClassName.
   
   #BIND(xsd:integer(SUBSTR(?yearlyTournamentName,0,4)) as ?year)
   #BIND(SUBSTR(?yearlyTournamentName,0,4)) as ?year)
   
   FILTER (?p not in (wdt:P155, wdt:P156))
}
#GROUP BY ?winner ?winnerName ?competitionClassName #?countryForSport  ?year
#HAVING (count(*) >=4)
#ORDER BY DESC (?year)
#ORDER BY DESC (?winnerName)
#ORDER BY DESC (?winnerName)
LIMIT 50

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q3130'), ('oName', 'Sydney')]
# [('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q3141'), ('oName', 'Melbourne')]
# [('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q60'), ('oName', 'New York City')]
# [('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q90'), ('oName', 'Paris')]
# [('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q5112'), ('oName', 'Adelaide')]
# [('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q736742'), ('oName', 'Wimbledon')]
# [('p', 'http://www.wikidata.org/prop/direct/P17'), ('pName', 'country'), ('o', 'http://www.wikidata.org/entity/Q142'), ('oName', 'France')]
# [('p', 'http://www.wikidata.org/prop/direct/P17'), ('pName', 'country'), ('o', 'http://www.wikidata.org/entity/Q145'), ('oName', 'United Kingdom')]
# [('p', 'http://www.wikidata.org/prop/direct/P17'), ('pName', 'country'), ('o', 'http://www.wikidata.org/entity/Q174193'), ('oName', 'United Kingdom of Great Britain and Ireland')]
# [('p', 'http://www.wikidata.org/prop/direct/P17'), ('pName', 'country'), ('o', 'http://www.wikidata.org/entity/Q30'), ('oName', 'United States of America')]
# [('p', 'http://www.wikidata.org/prop/direct/P17'), ('pName', 'country'), ('o', 'http://www.wikidata.org/entity/Q408'), ('oName', 'Australia')]
# [('p', 'http://www.wikidata.org/prop/direct/P2094'), ('pName', 'competition class'), ('o', 'http://www.wikidata.org/entity/Q920057'), ('oName', "women's sports")]
# [('p', 'http://www.wikidata.org/prop/direct/P276'), ('pName', 'location'), ('o', 'http://www.wikidata.org/entity/Q1613027'), ('oName', 'Stade Roland-Garros')]
# [('p', 'http://www.wikidata.org/prop/direct/P276'), ('pName', 'location'), ('o', 'http://www.wikidata.org/entity/Q7994559'), ('oName', 'White City Stadium')]
# [('p', 'http://www.wikidata.org/prop/direct/P276'), ('pName', 'location'), ('o', 'http://www.wikidata.org/entity/Q815369'), ('oName', 'All England Lawn Tennis and Croquet Club')]
# [('p', 'http://www.wikidata.org/prop/direct/P276'), ('pName', 'location'), ('o', 'http://www.wikidata.org/entity/Q1852081'), ('oName', 'USTA Billie Jean King National Tennis Center')]
# [('p', 'http://www.wikidata.org/prop/direct/P276'), ('pName', 'location'), ('o', 'http://www.wikidata.org/entity/Q2228393'), ('oName', 'Melbourne Park')]
# [('p', 'http://www.wikidata.org/prop/direct/P276'), ('pName', 'location'), ('o', 'http://www.wikidata.org/entity/Q60'), ('oName', 'New York City')]
# [('p', 'http://www.wikidata.org/prop/direct/P276'), ('pName', 'location'), ('o', 'http://www.wikidata.org/entity/Q84'), ('oName', 'London')]
# [('p', 'http://www.wikidata.org/prop/direct/P276'), ('pName', 'location'), ('o', 'http://www.wikidata.org/entity/Q3387742'), ('oName', 'West Side Tennis Club')]
# [('p', 'http://www.wikidata.org/prop/direct/P276'), ('pName', 'location'), ('o', 'http://www.wikidata.org/entity/Q6430893'), ('oName', 'Kooyong Stadium')]
# [('p', 'http://www.wikidata.org/prop/direct/P276'), ('pName', 'location'), ('o', 'http://www.wikidata.org/entity/Q6815403'), ('oName', 'Memorial Drive Tennis Centre')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('o', 'http://www.wikidata.org/entity/Q43605'), ('oName', 'French Open')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('o', 'http://www.wikidata.org/entity/Q47345468'), ('oName', 'tennis tournament edition')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('o', 'http://www.wikidata.org/entity/Q123577'), ('oName', 'US Open')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('o', 'http://www.wikidata.org/entity/Q41520'), ('oName', 'Wimbledon Championships')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('o', 'http://www.wikidata.org/entity/Q60874'), ('oName', 'Australian Open')]
# [('p', 'http://www.wikidata.org/prop/direct/P361'), ('pName', 'part of'), ('o', 'http://www.wikidata.org/entity/Q3741509'), ('oName', '2010 ITF Junior Circuit')]
# [('p', 'http://www.wikidata.org/prop/direct/P361'), ('pName', 'part of'), ('o', 'http://www.wikidata.org/entity/Q15020153'), ('oName', '2013 ITF Junior Circuit')]
# [('p', 'http://www.wikidata.org/prop/direct/P361'), ('pName', 'part of'), ('o', 'http://www.wikidata.org/entity/Q3789077'), ('oName', '2011 ITF Junior Circuit')]
# [('p', 'http://www.wikidata.org/prop/direct/P361'), ('pName', 'part of'), ('o', 'http://www.wikidata.org/entity/Q27910145'), ('oName', '2016 ITF Junior Circuit')]
# [('p', 'http://www.wikidata.org/prop/direct/P361'), ('pName', 'part of'), ('o', 'http://www.wikidata.org/entity/Q19828484'), ('oName', '2015 ITF Junior Circuit')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('o', 'http://www.wikidata.org/entity/Q15854755'), ('oName', "1978 Wimbledon Championships – Men's Doubles")]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('o', 'http://www.wikidata.org/entity/Q22231236'), ('oName', "2016 Australian Open – Boys' Doubles")]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('o', 'http://www.wikidata.org/entity/Q22956224'), ('oName', "2017 Australian Open – Men's Singles")]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('o', 'http://www.wikidata.org/entity/Q30098268'), ('oName', "2018 Wimbledon Championships – Women's Singles")]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('o', 'http://www.wikidata.org/entity/Q1455356'), ('oName', "1980 French Open – Women's Doubles")]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('o', 'http://www.wikidata.org/entity/Q1751593'), ('oName', "1958 Australian Championships – Men's Singles")]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('o', 'http://www.wikidata.org/entity/Q2311386'), ('oName', "1980 French Open – Men's Singles")]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('o', 'http://www.wikidata.org/entity/Q2406558'), ('oName', "1958 Australian Championships – Women's Singles")]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('o', 'http://www.wikidata.org/entity/Q3883664'), ('oName', '1980 French Open – Mixed Doubles')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('o', 'http://www.wikidata.org/entity/Q3883665'), ('oName', "1980 French Open – Men's Doubles")]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('o', 'http://www.wikidata.org/entity/Q536077'), ('oName', "1974 Wimbledon Championships – Men's Singles")]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('o', 'http://www.wikidata.org/entity/Q571749'), ('oName', "1988 US Open – Women's Singles")]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('o', 'http://www.wikidata.org/entity/Q925347'), ('oName', "1980 French Open – Women's Singles")]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('o', 'http://www.wikidata.org/entity/Q1972216'), ('oName', "1975 Australian Open – Men's Singles")]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('o', 'http://www.wikidata.org/entity/Q586490'), ('oName', "1972 Australian Open – Women's Singles")]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('o', 'http://www.wikidata.org/entity/Q594977'), ('oName', "1969 French Open – Women's Singles")]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('o', 'http://www.wikidata.org/entity/Q781699'), ('oName', "1975 Australian Open – Women's Singles")]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('o', 'http://www.wikidata.org/entity/Q1275316'), ('oName', "1957 Wimbledon Championships – Men's Doubles")]
# 50

# %%
# write your queries
# Consider the country for sport property of the tennis player (NO Country of citizenship). 
# Return the countries with at least one player who won at least one edition of each Grand Slam (the result set must be a list of country IRI and label).

# P31 ('instance of')
# P527 ('has part')
# P1346 ('winner')
# P1532 ('country for sport')

# FINDING shor way to GROUP something above yearlyTournament
# added more stuff FILTER and extended LIMIT


queryString = """

PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
SELECT DISTINCT ?p ?pName ?o ?oName #(COUNT(*) as ?tot) #?year ?countryForSport
WHERE {
   # All four tourmamets in Grand Slam
   VALUES (?tournament){
       (wd:Q43605)  # French Open
       (wd:Q123577) # US Open
       (wd:Q41520)  # Wimbledon Championships
       (wd:Q60874)  # Australian Open
   }
   # ?yearlyTournament wdt:P31 ?tournament.
   # ?yearlyTournament ?p ?o.
   #?subTournament wdt:P1346 ?winner;
   #                wdt:P2094 ?competitionClass.
   
   #?winner wdt:P1532 ?countryForSport.
   
   # get the label 
   # ?tournament sc:name ?tournamentName .
   # ?yearlyTournament sc:name ?yearlyTournamentName .
   # ?p sc:name ?pName.
   # ?o sc:name ?oName.
   #?subTournament sc:name ?subTournamentName.
   #?winner sc:name ?winnerName.
   #?competitionClass sc:name ?competitionClassName.
   
   #BIND(xsd:integer(SUBSTR(?yearlyTournamentName,0,4)) as ?year)
   #BIND(SUBSTR(?yearlyTournamentName,0,4)) as ?year)
   
   FILTER (?p not in (wdt:P155, wdt:P156, wdt:P527,wdt:P910, wdt:P276))
}
#GROUP BY ?winner ?winnerName ?competitionClassName #?countryForSport  ?year
#HAVING (count(*) >=4)
#ORDER BY DESC (?year)
#ORDER BY DESC (?winnerName)
#ORDER BY DESC (?winnerName)
LIMIT 100

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q3130'), ('oName', 'Sydney')]
# [('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q3141'), ('oName', 'Melbourne')]
# [('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q60'), ('oName', 'New York City')]
# [('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q90'), ('oName', 'Paris')]
# [('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q5112'), ('oName', 'Adelaide')]
# [('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q736742'), ('oName', 'Wimbledon')]
# [('p', 'http://www.wikidata.org/prop/direct/P17'), ('pName', 'country'), ('o', 'http://www.wikidata.org/entity/Q142'), ('oName', 'France')]
# [('p', 'http://www.wikidata.org/prop/direct/P17'), ('pName', 'country'), ('o', 'http://www.wikidata.org/entity/Q145'), ('oName', 'United Kingdom')]
# [('p', 'http://www.wikidata.org/prop/direct/P17'), ('pName', 'country'), ('o', 'http://www.wikidata.org/entity/Q174193'), ('oName', 'United Kingdom of Great Britain and Ireland')]
# [('p', 'http://www.wikidata.org/prop/direct/P17'), ('pName', 'country'), ('o', 'http://www.wikidata.org/entity/Q30'), ('oName', 'United States of America')]
# [('p', 'http://www.wikidata.org/prop/direct/P17'), ('pName', 'country'), ('o', 'http://www.wikidata.org/entity/Q408'), ('oName', 'Australia')]
# [('p', 'http://www.wikidata.org/prop/direct/P2094'), ('pName', 'competition class'), ('o', 'http://www.wikidata.org/entity/Q920057'), ('oName', "women's sports")]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('o', 'http://www.wikidata.org/entity/Q43605'), ('oName', 'French Open')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('o', 'http://www.wikidata.org/entity/Q47345468'), ('oName', 'tennis tournament edition')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('o', 'http://www.wikidata.org/entity/Q123577'), ('oName', 'US Open')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('o', 'http://www.wikidata.org/entity/Q41520'), ('oName', 'Wimbledon Championships')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('o', 'http://www.wikidata.org/entity/Q60874'), ('oName', 'Australian Open')]
# [('p', 'http://www.wikidata.org/prop/direct/P361'), ('pName', 'part of'), ('o', 'http://www.wikidata.org/entity/Q3741509'), ('oName', '2010 ITF Junior Circuit')]
# [('p', 'http://www.wikidata.org/prop/direct/P361'), ('pName', 'part of'), ('o', 'http://www.wikidata.org/entity/Q15020153'), ('oName', '2013 ITF Junior Circuit')]
# [('p', 'http://www.wikidata.org/prop/direct/P361'), ('pName', 'part of'), ('o', 'http://www.wikidata.org/entity/Q3789077'), ('oName', '2011 ITF Junior Circuit')]
# [('p', 'http://www.wikidata.org/prop/direct/P361'), ('pName', 'part of'), ('o', 'http://www.wikidata.org/entity/Q27910145'), ('oName', '2016 ITF Junior Circuit')]
# [('p', 'http://www.wikidata.org/prop/direct/P361'), ('pName', 'part of'), ('o', 'http://www.wikidata.org/entity/Q19828484'), ('oName', '2015 ITF Junior Circuit')]
# [('p', 'http://www.wikidata.org/prop/direct/P641'), ('pName', 'sport'), ('o', 'http://www.wikidata.org/entity/Q847'), ('oName', 'tennis')]
# [('p', 'http://www.wikidata.org/prop/direct/P664'), ('pName', 'organizer'), ('o', 'http://www.wikidata.org/entity/Q223041'), ('oName', 'International Tennis Federation')]
# [('p', 'http://www.wikidata.org/prop/direct/P664'), ('pName', 'organizer'), ('o', 'http://www.wikidata.org/entity/Q1156323'), ('oName', 'United States Tennis Association')]
# [('p', 'http://www.wikidata.org/prop/direct/P765'), ('pName', 'surface played on'), ('o', 'http://www.wikidata.org/entity/Q198718'), ('oName', 'clay court')]
# [('p', 'http://www.wikidata.org/prop/direct/P765'), ('pName', 'surface played on'), ('o', 'http://www.wikidata.org/entity/Q1151291'), ('oName', 'grass court')]
# [('p', 'http://www.wikidata.org/prop/direct/P765'), ('pName', 'surface played on'), ('o', 'http://www.wikidata.org/entity/Q47678177'), ('oName', 'grass')]
# [('p', 'http://www.wikidata.org/prop/direct/P765'), ('pName', 'surface played on'), ('o', 'http://www.wikidata.org/entity/Q47777555'), ('oName', 'hardcourt surface')]
# [('p', 'http://www.wikidata.org/prop/direct/P7959'), ('pName', 'historic county'), ('o', 'http://www.wikidata.org/entity/Q67443130'), ('oName', 'Surrey')]
# [('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q34932'), ('oName', 'Brisbane')]
# [('p', 'http://www.wikidata.org/prop/direct/P3450'), ('pName', 'sports season of league or competition'), ('o', 'http://www.wikidata.org/entity/Q41520'), ('oName', 'Wimbledon Championships')]
# [('p', 'http://www.wikidata.org/prop/direct/P361'), ('pName', 'part of'), ('o', 'http://www.wikidata.org/entity/Q71973693'), ('oName', '2020 WTA Tour')]
# [('p', 'http://www.wikidata.org/prop/direct/P361'), ('pName', 'part of'), ('o', 'http://www.wikidata.org/entity/Q3789078'), ('oName', '2012 ITF Junior Circuit')]
# [('p', 'http://www.wikidata.org/prop/direct/P361'), ('pName', 'part of'), ('o', 'http://www.wikidata.org/entity/Q104295273'), ('oName', '2021 WTA Tour')]
# [('p', 'http://www.wikidata.org/prop/direct/P361'), ('pName', 'part of'), ('o', 'http://www.wikidata.org/entity/Q85737870'), ('oName', '2021 ATP Tour')]
# [('p', 'http://www.wikidata.org/prop/direct/P361'), ('pName', 'part of'), ('o', 'http://www.wikidata.org/entity/Q62083037'), ('oName', '2020 ATP Tour')]
# [('p', 'http://www.wikidata.org/prop/direct/P361'), ('pName', 'part of'), ('o', 'http://www.wikidata.org/entity/Q17633649'), ('oName', '2014 ITF Junior Circuit')]
# [('p', 'http://www.wikidata.org/prop/direct/P765'), ('pName', 'surface played on'), ('o', 'http://www.wikidata.org/entity/Q47676928'), ('oName', 'clay')]
# [('p', 'http://www.wikidata.org/prop/direct/P2094'), ('pName', 'competition class'), ('o', 'http://www.wikidata.org/entity/Q16893072'), ('oName', "men's singles")]
# [('p', 'http://www.wikidata.org/prop/direct/P361'), ('pName', 'part of'), ('o', 'http://www.wikidata.org/entity/Q12780091'), ('oName', '2014 Australian Open')]
# [('p', 'http://www.wikidata.org/prop/direct/P361'), ('pName', 'part of'), ('o', 'http://www.wikidata.org/entity/Q22690923'), ('oName', '2016 French Open')]
# [('p', 'http://www.wikidata.org/prop/direct/P361'), ('pName', 'part of'), ('o', 'http://www.wikidata.org/entity/Q2783503'), ('oName', "2013 Australian Open – Men's Singles")]
# 43

# %%
# write your queries
# Consider the country for sport property of the tennis player (NO Country of citizenship). 
# Return the countries with at least one player who won at least one edition of each Grand Slam (the result set must be a list of country IRI and label).

# P31 ('instance of')
# P527 ('has part')
# P1346 ('winner')
# P1532 ('country for sport')

# FINDING shor way to GROUP something above yearlyTournament 
# added more stuff (x2) FILTER and extended LIMIT


queryString = """

PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
SELECT DISTINCT ?p ?pName ?o ?oName #(COUNT(*) as ?tot) #?year ?countryForSport
WHERE {
   # All four tourmamets in Grand Slam
   VALUES (?tournament){
       (wd:Q43605)  # French Open
       (wd:Q123577) # US Open
       (wd:Q41520)  # Wimbledon Championships
       (wd:Q60874)  # Australian Open
   }
   # ?yearlyTournament wdt:P31 ?tournament.
   # ?yearlyTournament ?p ?o.
   #?subTournament wdt:P1346 ?winner;
   #                wdt:P2094 ?competitionClass.
   
   #?winner wdt:P1532 ?countryForSport.
   
   # get the label 
   # ?tournament sc:name ?tournamentName .
   # ?yearlyTournament sc:name ?yearlyTournamentName .
   # ?p sc:name ?pName.
   # ?o sc:name ?oName.
   #?subTournament sc:name ?subTournamentName.
   #?winner sc:name ?winnerName.
   #?competitionClass sc:name ?competitionClassName.
   
   #BIND(xsd:integer(SUBSTR(?yearlyTournamentName,0,4)) as ?year)
   #BIND(SUBSTR(?yearlyTournamentName,0,4)) as ?year)
   
   FILTER (?p not in (wdt:P155, wdt:P156, wdt:P527,wdt:P910, wdt:P276, wdt:P361))
}
#GROUP BY ?winner ?winnerName ?competitionClassName #?countryForSport  ?year
#HAVING (count(*) >=4)
#ORDER BY DESC (?year)
#ORDER BY DESC (?winnerName)
#ORDER BY DESC (?winnerName)
LIMIT 100

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q3130'), ('oName', 'Sydney')]
# [('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q3141'), ('oName', 'Melbourne')]
# [('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q60'), ('oName', 'New York City')]
# [('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q90'), ('oName', 'Paris')]
# [('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q5112'), ('oName', 'Adelaide')]
# [('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q736742'), ('oName', 'Wimbledon')]
# [('p', 'http://www.wikidata.org/prop/direct/P17'), ('pName', 'country'), ('o', 'http://www.wikidata.org/entity/Q142'), ('oName', 'France')]
# [('p', 'http://www.wikidata.org/prop/direct/P17'), ('pName', 'country'), ('o', 'http://www.wikidata.org/entity/Q145'), ('oName', 'United Kingdom')]
# [('p', 'http://www.wikidata.org/prop/direct/P17'), ('pName', 'country'), ('o', 'http://www.wikidata.org/entity/Q174193'), ('oName', 'United Kingdom of Great Britain and Ireland')]
# [('p', 'http://www.wikidata.org/prop/direct/P17'), ('pName', 'country'), ('o', 'http://www.wikidata.org/entity/Q30'), ('oName', 'United States of America')]
# [('p', 'http://www.wikidata.org/prop/direct/P17'), ('pName', 'country'), ('o', 'http://www.wikidata.org/entity/Q408'), ('oName', 'Australia')]
# [('p', 'http://www.wikidata.org/prop/direct/P2094'), ('pName', 'competition class'), ('o', 'http://www.wikidata.org/entity/Q920057'), ('oName', "women's sports")]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('o', 'http://www.wikidata.org/entity/Q43605'), ('oName', 'French Open')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('o', 'http://www.wikidata.org/entity/Q47345468'), ('oName', 'tennis tournament edition')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('o', 'http://www.wikidata.org/entity/Q123577'), ('oName', 'US Open')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('o', 'http://www.wikidata.org/entity/Q41520'), ('oName', 'Wimbledon Championships')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('o', 'http://www.wikidata.org/entity/Q60874'), ('oName', 'Australian Open')]
# [('p', 'http://www.wikidata.org/prop/direct/P641'), ('pName', 'sport'), ('o', 'http://www.wikidata.org/entity/Q847'), ('oName', 'tennis')]
# [('p', 'http://www.wikidata.org/prop/direct/P664'), ('pName', 'organizer'), ('o', 'http://www.wikidata.org/entity/Q223041'), ('oName', 'International Tennis Federation')]
# [('p', 'http://www.wikidata.org/prop/direct/P664'), ('pName', 'organizer'), ('o', 'http://www.wikidata.org/entity/Q1156323'), ('oName', 'United States Tennis Association')]
# [('p', 'http://www.wikidata.org/prop/direct/P765'), ('pName', 'surface played on'), ('o', 'http://www.wikidata.org/entity/Q198718'), ('oName', 'clay court')]
# [('p', 'http://www.wikidata.org/prop/direct/P765'), ('pName', 'surface played on'), ('o', 'http://www.wikidata.org/entity/Q1151291'), ('oName', 'grass court')]
# [('p', 'http://www.wikidata.org/prop/direct/P765'), ('pName', 'surface played on'), ('o', 'http://www.wikidata.org/entity/Q47678177'), ('oName', 'grass')]
# [('p', 'http://www.wikidata.org/prop/direct/P765'), ('pName', 'surface played on'), ('o', 'http://www.wikidata.org/entity/Q47777555'), ('oName', 'hardcourt surface')]
# [('p', 'http://www.wikidata.org/prop/direct/P7959'), ('pName', 'historic county'), ('o', 'http://www.wikidata.org/entity/Q67443130'), ('oName', 'Surrey')]
# [('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q34932'), ('oName', 'Brisbane')]
# [('p', 'http://www.wikidata.org/prop/direct/P3450'), ('pName', 'sports season of league or competition'), ('o', 'http://www.wikidata.org/entity/Q41520'), ('oName', 'Wimbledon Championships')]
# [('p', 'http://www.wikidata.org/prop/direct/P765'), ('pName', 'surface played on'), ('o', 'http://www.wikidata.org/entity/Q47676928'), ('oName', 'clay')]
# [('p', 'http://www.wikidata.org/prop/direct/P2094'), ('pName', 'competition class'), ('o', 'http://www.wikidata.org/entity/Q16893072'), ('oName', "men's singles")]
# 29

# %%
# write your queries
# Consider the country for sport property of the tennis player (NO Country of citizenship). 
# Return the countries with at least one player who won at least one edition of each Grand Slam (the result set must be a list of country IRI and label).

# P31 ('instance of')
# P527 ('has part')
# P1346 ('winner')
# P1532 ('country for sport')

# FINDING shor way to GROUP something above yearlyTournament 
# FILTER ?p to P3450 ('sports season of league or competition')

queryString = """

PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
SELECT DISTINCT ?p ?pName ?o ?oName #(COUNT(*) as ?tot) #?year ?countryForSport
WHERE {
   # All four tourmamets in Grand Slam
   VALUES (?tournament){
       (wd:Q43605)  # French Open
       (wd:Q123577) # US Open
       (wd:Q41520)  # Wimbledon Championships
       (wd:Q60874)  # Australian Open
   }
   # ?yearlyTournament wdt:P31 ?tournament.
   # ?yearlyTournament ?p ?o.
   #?subTournament wdt:P1346 ?winner;
   #                wdt:P2094 ?competitionClass.
   
   #?winner wdt:P1532 ?countryForSport.
   
   # get the label 
   # ?tournament sc:name ?tournamentName .
   # ?yearlyTournament sc:name ?yearlyTournamentName .
   # ?p sc:name ?pName.
   # ?o sc:name ?oName.
   #?subTournament sc:name ?subTournamentName.
   #?winner sc:name ?winnerName.
   #?competitionClass sc:name ?competitionClassName.
   
   #BIND(xsd:integer(SUBSTR(?yearlyTournamentName,0,4)) as ?year)
   #BIND(SUBSTR(?yearlyTournamentName,0,4)) as ?year)
   
   #FILTER (?p not in (wdt:P155, wdt:P156, wdt:P527,wdt:P910, wdt:P276, wdt:P361))
   FILTER (?p in (wdt:P3450))
}
#GROUP BY ?winner ?winnerName ?competitionClassName #?countryForSport  ?year
#HAVING (count(*) >=4)
#ORDER BY DESC (?year)
#ORDER BY DESC (?winnerName)
#ORDER BY DESC (?winnerName)
LIMIT 100

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P3450'), ('pName', 'sports season of league or competition'), ('o', 'http://www.wikidata.org/entity/Q41520'), ('oName', 'Wimbledon Championships')]
# 1

# %%
# write your queries
# Consider the country for sport property of the tennis player (NO Country of citizenship). 
# Return the countries with at least one player who won at least one edition of each Grand Slam (the result set must be a list of country IRI and label).

# P31 ('instance of')
# P527 ('has part')
# P1346 ('winner')
# P1532 ('country for sport')

# FINDING shor way to GROUP something above yearlyTournament 
# FILTER ?p to P31, P3450 ('sports season of league or competition') has only 1 result

queryString = """

PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
SELECT DISTINCT ?p ?pName ?o ?oName #(COUNT(*) as ?tot) #?year ?countryForSport
WHERE {
   # All four tourmamets in Grand Slam
   VALUES (?tournament){
       (wd:Q43605)  # French Open
       (wd:Q123577) # US Open
       (wd:Q41520)  # Wimbledon Championships
       (wd:Q60874)  # Australian Open
   }
   # ?yearlyTournament wdt:P31 ?tournament.
   # ?yearlyTournament ?p ?o.
   #?subTournament wdt:P1346 ?winner;
   #                wdt:P2094 ?competitionClass.
   
   #?winner wdt:P1532 ?countryForSport.
   
   # get the label 
   # ?tournament sc:name ?tournamentName .
   # ?yearlyTournament sc:name ?yearlyTournamentName .
   # ?p sc:name ?pName.
   # ?o sc:name ?oName.
   #?subTournament sc:name ?subTournamentName.
   #?winner sc:name ?winnerName.
   #?competitionClass sc:name ?competitionClassName.
   
   #BIND(xsd:integer(SUBSTR(?yearlyTournamentName,0,4)) as ?year)
   #BIND(SUBSTR(?yearlyTournamentName,0,4)) as ?year)
   
   #FILTER (?p not in (wdt:P155, wdt:P156, wdt:P527,wdt:P910, wdt:P276, wdt:P361))
   FILTER (?p in (wdt:P31))
}
#GROUP BY ?winner ?winnerName ?competitionClassName #?countryForSport  ?year
#HAVING (count(*) >=4)
#ORDER BY DESC (?year)
#ORDER BY DESC (?winnerName)
#ORDER BY DESC (?winnerName)
LIMIT 100

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('o', 'http://www.wikidata.org/entity/Q43605'), ('oName', 'French Open')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('o', 'http://www.wikidata.org/entity/Q47345468'), ('oName', 'tennis tournament edition')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('o', 'http://www.wikidata.org/entity/Q123577'), ('oName', 'US Open')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('o', 'http://www.wikidata.org/entity/Q41520'), ('oName', 'Wimbledon Championships')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('o', 'http://www.wikidata.org/entity/Q60874'), ('oName', 'Australian Open')]
# 5

# %%
# write your queries
# Consider the country for sport property of the tennis player (NO Country of citizenship). 
# Return the countries with at least one player who won at least one edition of each Grand Slam (the result set must be a list of country IRI and label).

# P31 ('instance of')
# P527 ('has part')
# P1346 ('winner')
# P1532 ('country for sport')

# FINDING shor way to group by instead of doing inner queries
# FILTER ?p to P31 --> is what I was already doing = ?tournament
# RECOVER initial query

queryString = """

PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
SELECT DISTINCT ?winner ?winnerName ?tournamentName ?subTournamentName
WHERE {
   # All four tourmamets in Grand Slam
   VALUES (?tournament){
       (wd:Q43605)  # French Open
       (wd:Q123577) # US Open
       (wd:Q41520)  # Wimbledon Championships
       (wd:Q60874)  # Australian Open
   }
   # ?yearlyTournament wdt:P31 ?tournament.
   # ?yearlyTournament wdt:P527 ?subTournament.
   # ?subTournament wdt:P1346 ?winner;
                   wdt:P2094 ?competitionClass.
   
   # ?winner wdt:P1532 ?countryForSport.
   
   # get the label 
   # ?tournament sc:name ?tournamentName .
   # ?yearlyTournament sc:name ?yearlyTournamentName .
   # ?subTournament sc:name ?subTournamentName.
   # ?winner sc:name ?winnerName.
   # ?competitionClass sc:name ?competitionClassName.
}
ORDER BY asc (?winnerName)
LIMIT 20

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('winner', 'http://www.wikidata.org/entity/Q54668'), ('winnerName', 'Abigail Spears'), ('tournamentName', 'Australian Open'), ('subTournamentName', '2017 Australian Open – Mixed Doubles')]
# [('winner', 'http://www.wikidata.org/entity/Q207352'), ('winnerName', 'Agnieszka Radwańska'), ('tournamentName', 'French Open'), ('subTournamentName', "2006 French Open – Girls' Singles")]
# [('winner', 'http://www.wikidata.org/entity/Q229100'), ('winnerName', 'Ai Sugiyama'), ('tournamentName', 'US Open'), ('subTournamentName', '1999 US Open – Mixed Doubles')]
# [('winner', 'http://www.wikidata.org/entity/Q229100'), ('winnerName', 'Ai Sugiyama'), ('tournamentName', 'Wimbledon Championships'), ('subTournamentName', "2003 Wimbledon Championships – Women's Doubles")]
# [('winner', 'http://www.wikidata.org/entity/Q2712407'), ('winnerName', 'Ajla Tomljanović'), ('tournamentName', 'Australian Open'), ('subTournamentName', "2009 Australian Open – Girls' Doubles")]
# [('winner', 'http://www.wikidata.org/entity/Q317828'), ('winnerName', 'Albert Costa'), ('tournamentName', 'French Open'), ('subTournamentName', "2002 French Open – Men's Singles")]
# [('winner', 'http://www.wikidata.org/entity/Q737425'), ('winnerName', "Alex O'Brien"), ('tournamentName', 'US Open'), ('subTournamentName', "1999 US Open – Men's Doubles")]
# [('winner', 'http://www.wikidata.org/entity/Q734544'), ('winnerName', 'Alex Olmedo'), ('tournamentName', 'Australian Open'), ('subTournamentName', "1959 Australian Championships – Men's Singles")]
# [('winner', 'http://www.wikidata.org/entity/Q734544'), ('winnerName', 'Alex Olmedo'), ('tournamentName', 'Wimbledon Championships'), ('subTournamentName', "1959 Wimbledon Championships – Men's Singles")]
# [('winner', 'http://www.wikidata.org/entity/Q457476'), ('winnerName', 'Alexander Peya'), ('tournamentName', 'Wimbledon Championships'), ('subTournamentName', '2018 Wimbledon Championships – Mixed Doubles')]
# [('winner', 'http://www.wikidata.org/entity/Q13990552'), ('winnerName', 'Alexander Zverev'), ('tournamentName', 'Australian Open'), ('subTournamentName', "2014 Australian Open – Boys' Singles")]
# [('winner', 'http://www.wikidata.org/entity/Q2834043'), ('winnerName', 'Alexandre Sidorenko'), ('tournamentName', 'Australian Open'), ('subTournamentName', "2006 Australian Open – Boys' Singles")]
# [('winner', 'http://www.wikidata.org/entity/Q333104'), ('winnerName', 'Aline Terry'), ('tournamentName', 'US Open'), ('subTournamentName', "1893 U.S. National Championships – Women's Singles")]
# [('winner', 'http://www.wikidata.org/entity/Q229002'), ('winnerName', 'Alizé Cornet'), ('tournamentName', 'French Open'), ('subTournamentName', "2007 French Open – Girls' Singles")]
# [('winner', 'http://www.wikidata.org/entity/Q231962'), ('winnerName', 'Alona Bondarenko'), ('tournamentName', 'Australian Open'), ('subTournamentName', "2008 Australian Open – Women's Doubles")]
# [('winner', 'http://www.wikidata.org/entity/Q53550'), ('winnerName', 'Althea Gibson'), ('tournamentName', 'Wimbledon Championships'), ('subTournamentName', "1956 Wimbledon Championships – Women's Doubles")]
# [('winner', 'http://www.wikidata.org/entity/Q53550'), ('winnerName', 'Althea Gibson'), ('tournamentName', 'Wimbledon Championships'), ('subTournamentName', "1957 Wimbledon Championships – Women's Singles")]
# [('winner', 'http://www.wikidata.org/entity/Q53550'), ('winnerName', 'Althea Gibson'), ('tournamentName', 'Wimbledon Championships'), ('subTournamentName', "1957 Wimbledon Championships – Women's Doubles")]
# [('winner', 'http://www.wikidata.org/entity/Q53550'), ('winnerName', 'Althea Gibson'), ('tournamentName', 'Wimbledon Championships'), ('subTournamentName', "1958 Wimbledon Championships – Women's Singles")]
# [('winner', 'http://www.wikidata.org/entity/Q53550'), ('winnerName', 'Althea Gibson'), ('tournamentName', 'Wimbledon Championships'), ('subTournamentName', "1958 Wimbledon Championships – Women's Doubles")]
# 20

# %% [markdown]
# ##### Partial sol found: got all wins of each person in each tournament:

# %%
# write your queries
# Consider the country for sport property of the tennis player (NO Country of citizenship). 
# Return the countries with at least one player who won at least one edition of each Grand Slam (the result set must be a list of country IRI and label).

# P31 ('instance of')
# P527 ('has part')
# P1346 ('winner')
# P1532 ('country for sport')

# GROUP BY ?winner & ?tournament


queryString = """

PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
SELECT DISTINCT ?winner ?winnerName ?tournamentName (COUNT(*) AS ?tot)
WHERE {
   # All four tourmamets in Grand Slam
   VALUES (?tournament){
       (wd:Q43605)  # French Open
       (wd:Q123577) # US Open
       (wd:Q41520)  # Wimbledon Championships
       (wd:Q60874)  # Australian Open
   }
   # ?yearlyTournament wdt:P31 ?tournament.
   # ?yearlyTournament wdt:P527 ?subTournament.
   # ?subTournament wdt:P1346 ?winner;
                   wdt:P2094 ?competitionClass.
   
   # ?winner wdt:P1532 ?countryForSport.
   
   # get the label 
   # ?tournament sc:name ?tournamentName .
   # ?yearlyTournament sc:name ?yearlyTournamentName .
   # ?subTournament sc:name ?subTournamentName.
   # ?winner sc:name ?winnerName.
   # ?competitionClass sc:name ?competitionClassName.
}
GROUP BY ?winner ?winnerName ?tournamentName
ORDER BY DESC (?tot)
LIMIT 20

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('winner', 'http://www.wikidata.org/entity/Q54545'), ('winnerName', 'Martina Navratilova'), ('tournamentName', 'Wimbledon Championships'), ('tot', '51')]
# [('winner', 'http://www.wikidata.org/entity/Q54545'), ('winnerName', 'Martina Navratilova'), ('tournamentName', 'Australian Open'), ('tot', '33')]
# [('winner', 'http://www.wikidata.org/entity/Q54545'), ('winnerName', 'Martina Navratilova'), ('tournamentName', 'US Open'), ('tot', '33')]
# [('winner', 'http://www.wikidata.org/entity/Q54545'), ('winnerName', 'Martina Navratilova'), ('tournamentName', 'French Open'), ('tot', '30')]
# [('winner', 'http://www.wikidata.org/entity/Q11459'), ('winnerName', 'Serena Williams'), ('tournamentName', 'Wimbledon Championships'), ('tot', '14')]
# [('winner', 'http://www.wikidata.org/entity/Q10132'), ('winnerName', 'Rafael Nadal'), ('tournamentName', 'French Open'), ('tot', '13')]
# [('winner', 'http://www.wikidata.org/entity/Q229121'), ('winnerName', 'Jana Novotná'), ('tournamentName', 'Wimbledon Championships'), ('tot', '12')]
# [('winner', 'http://www.wikidata.org/entity/Q11578'), ('winnerName', 'Venus Williams'), ('tournamentName', 'Wimbledon Championships'), ('tot', '11')]
# [('winner', 'http://www.wikidata.org/entity/Q11459'), ('winnerName', 'Serena Williams'), ('tournamentName', 'Australian Open'), ('tot', '11')]
# [('winner', 'http://www.wikidata.org/entity/Q134720'), ('winnerName', 'Martina Hingis'), ('tournamentName', 'Australian Open'), ('tot', '10')]
# [('winner', 'http://www.wikidata.org/entity/Q5812'), ('winnerName', 'Novak Djokovic'), ('tournamentName', 'Australian Open'), ('tot', '9')]
# [('winner', 'http://www.wikidata.org/entity/Q173633'), ('winnerName', 'Monica Seles'), ('tournamentName', 'Australian Open'), ('tot', '8')]
# [('winner', 'http://www.wikidata.org/entity/Q1426'), ('winnerName', 'Roger Federer'), ('tournamentName', 'Wimbledon Championships'), ('tot', '8')]
# [('winner', 'http://www.wikidata.org/entity/Q11662'), ('winnerName', 'Steffi Graf'), ('tournamentName', 'Wimbledon Championships'), ('tot', '8')]
# [('winner', 'http://www.wikidata.org/entity/Q229121'), ('winnerName', 'Jana Novotná'), ('tournamentName', 'Australian Open'), ('tot', '8')]
# [('winner', 'http://www.wikidata.org/entity/Q229151'), ('winnerName', 'Helena Suková'), ('tournamentName', 'Wimbledon Championships'), ('tot', '7')]
# [('winner', 'http://www.wikidata.org/entity/Q14286'), ('winnerName', 'Chris Evert'), ('tournamentName', 'French Open'), ('tot', '7')]
# [('winner', 'http://www.wikidata.org/entity/Q365139'), ('winnerName', 'William Renshaw'), ('tournamentName', 'Wimbledon Championships'), ('tot', '6')]
# [('winner', 'http://www.wikidata.org/entity/Q134720'), ('winnerName', 'Martina Hingis'), ('tournamentName', 'Wimbledon Championships'), ('tot', '6')]
# [('winner', 'http://www.wikidata.org/entity/Q1426'), ('winnerName', 'Roger Federer'), ('tournamentName', 'Australian Open'), ('tot', '6')]
# 20

# %%
# write your queries
# Consider the country for sport property of the tennis player (NO Country of citizenship). 
# Return the countries with at least one player who won at least one edition of each Grand Slam (the result set must be a list of country IRI and label).

# P31 ('instance of')
# P527 ('has part')
# P1346 ('winner')
# P1532 ('country for sport')

# GROUP BY ?winner & ?tournament
# -> ORDERING & EXTENDING LIMIT TO 50


queryString = """

PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
SELECT DISTINCT ?winner ?winnerName ?tournamentName (COUNT(*) AS ?tot)
WHERE {
   # All four tourmamets in Grand Slam
   VALUES (?tournament){
       (wd:Q43605)  # French Open
       (wd:Q123577) # US Open
       (wd:Q41520)  # Wimbledon Championships
       (wd:Q60874)  # Australian Open
   }
   # ?yearlyTournament wdt:P31 ?tournament.
   # ?yearlyTournament wdt:P527 ?subTournament.
   # ?subTournament wdt:P1346 ?winner;
                   wdt:P2094 ?competitionClass.
   
   # ?winner wdt:P1532 ?countryForSport.
   
   # get the label 
   # ?tournament sc:name ?tournamentName .
   # ?yearlyTournament sc:name ?yearlyTournamentName .
   # ?subTournament sc:name ?subTournamentName.
   # ?winner sc:name ?winnerName.
   # ?competitionClass sc:name ?competitionClassName.
}
GROUP BY ?winner ?winnerName ?tournamentName
ORDER BY ?winnerName ?tot
LIMIT 50

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('winner', 'http://www.wikidata.org/entity/Q54668'), ('winnerName', 'Abigail Spears'), ('tournamentName', 'Australian Open'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q207352'), ('winnerName', 'Agnieszka Radwańska'), ('tournamentName', 'French Open'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q229100'), ('winnerName', 'Ai Sugiyama'), ('tournamentName', 'US Open'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q229100'), ('winnerName', 'Ai Sugiyama'), ('tournamentName', 'Wimbledon Championships'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q2712407'), ('winnerName', 'Ajla Tomljanović'), ('tournamentName', 'Australian Open'), ('tot', '2')]
# [('winner', 'http://www.wikidata.org/entity/Q317828'), ('winnerName', 'Albert Costa'), ('tournamentName', 'French Open'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q737425'), ('winnerName', "Alex O'Brien"), ('tournamentName', 'US Open'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q734544'), ('winnerName', 'Alex Olmedo'), ('tournamentName', 'Australian Open'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q734544'), ('winnerName', 'Alex Olmedo'), ('tournamentName', 'Wimbledon Championships'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q457476'), ('winnerName', 'Alexander Peya'), ('tournamentName', 'Wimbledon Championships'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q13990552'), ('winnerName', 'Alexander Zverev'), ('tournamentName', 'Australian Open'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q2834043'), ('winnerName', 'Alexandre Sidorenko'), ('tournamentName', 'Australian Open'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q333104'), ('winnerName', 'Aline Terry'), ('tournamentName', 'US Open'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q229002'), ('winnerName', 'Alizé Cornet'), ('tournamentName', 'French Open'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q231962'), ('winnerName', 'Alona Bondarenko'), ('tournamentName', 'Australian Open'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q53550'), ('winnerName', 'Althea Gibson'), ('tournamentName', 'French Open'), ('tot', '2')]
# [('winner', 'http://www.wikidata.org/entity/Q53550'), ('winnerName', 'Althea Gibson'), ('tournamentName', 'Wimbledon Championships'), ('tot', '5')]
# [('winner', 'http://www.wikidata.org/entity/Q24456716'), ('winnerName', 'Amanda Anisimova'), ('tournamentName', 'US Open'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q180872'), ('winnerName', 'Amélie Mauresmo'), ('tournamentName', 'Australian Open'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q180872'), ('winnerName', 'Amélie Mauresmo'), ('tournamentName', 'Wimbledon Championships'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q454683'), ('winnerName', 'An-Sophie Mestach'), ('tournamentName', 'Australian Open'), ('tot', '2')]
# [('winner', 'http://www.wikidata.org/entity/Q30758'), ('winnerName', 'Ana Ivanovic'), ('tournamentName', 'French Open'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q2365460'), ('winnerName', 'Ana Konjuh'), ('tournamentName', 'US Open'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q2365460'), ('winnerName', 'Ana Konjuh'), ('tournamentName', 'Australian Open'), ('tot', '2')]
# [('winner', 'http://www.wikidata.org/entity/Q219724'), ('winnerName', 'Anabel Medina Garrigues'), ('tournamentName', 'French Open'), ('tot', '2')]
# [('winner', 'http://www.wikidata.org/entity/Q203591'), ('winnerName', 'Anastasia Myskina'), ('tournamentName', 'French Open'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q487182'), ('winnerName', 'Anastasia Pavlyuchenkova'), ('tournamentName', 'Australian Open'), ('tot', '3')]
# [('winner', 'http://www.wikidata.org/entity/Q455136'), ('winnerName', 'Anders Järryd'), ('tournamentName', 'US Open'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q455136'), ('winnerName', 'Anders Järryd'), ('tournamentName', 'French Open'), ('tot', '3')]
# [('winner', 'http://www.wikidata.org/entity/Q455136'), ('winnerName', 'Anders Järryd'), ('tournamentName', 'Wimbledon Championships'), ('tot', '3')]
# [('winner', 'http://www.wikidata.org/entity/Q236648'), ('winnerName', 'Andrea Jaeger'), ('tournamentName', 'French Open'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q11581'), ('winnerName', 'Andrea Sestini Hlaváčková'), ('tournamentName', 'French Open'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q11581'), ('winnerName', 'Andrea Sestini Hlaváčková'), ('tournamentName', 'US Open'), ('tot', '2')]
# [('winner', 'http://www.wikidata.org/entity/Q18223058'), ('winnerName', 'Andreas Mies'), ('tournamentName', 'French Open'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q502583'), ('winnerName', 'Andrei Olhovskiy'), ('tournamentName', 'Australian Open'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q502583'), ('winnerName', 'Andrei Olhovskiy'), ('tournamentName', 'French Open'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q315958'), ('winnerName', 'Andrés Gimeno'), ('tournamentName', 'French Open'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q10125'), ('winnerName', 'Andy Murray'), ('tournamentName', 'Wimbledon Championships'), ('tot', '2')]
# [('winner', 'http://www.wikidata.org/entity/Q442632'), ('winnerName', 'Angela Buxton'), ('tournamentName', 'Wimbledon Championships'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q442632'), ('winnerName', 'Angela Buxton'), ('tournamentName', 'French Open'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q241727'), ('winnerName', 'Angela Mortimer'), ('tournamentName', 'Australian Open'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q241727'), ('winnerName', 'Angela Mortimer'), ('tournamentName', 'French Open'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q241727'), ('winnerName', 'Angela Mortimer'), ('tournamentName', 'Wimbledon Championships'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q77178'), ('winnerName', 'Angelique Kerber'), ('tournamentName', 'Wimbledon Championships'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q77178'), ('winnerName', 'Angelique Kerber'), ('tournamentName', 'Australian Open'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q77178'), ('winnerName', 'Angelique Kerber'), ('tournamentName', 'US Open'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q15642606'), ('winnerName', 'Anhelina Kalinina'), ('tournamentName', 'Australian Open'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q259356'), ('winnerName', 'Ann Haydon-Jones'), ('tournamentName', 'Australian Open'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q259356'), ('winnerName', 'Ann Haydon-Jones'), ('tournamentName', 'French Open'), ('tot', '3')]
# [('winner', 'http://www.wikidata.org/entity/Q458438'), ('winnerName', 'Ann Kiyomura'), ('tournamentName', 'Wimbledon Championships'), ('tot', '1')]
# 50

# %%
# write your queries
# Consider the country for sport property of the tennis player (NO Country of citizenship). 
# Return the countries with at least one player who won at least one edition of each Grand Slam (the result set must be a list of country IRI and label).

# P31 ('instance of')
# P527 ('has part')
# P1346 ('winner')
# P1532 ('country for sport')

# GROUP BY ?winner & ?tournament
# ORDERING
# -> LIMIT extended to 100


queryString = """

PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
SELECT DISTINCT ?winner ?winnerName ?tournamentName (COUNT(*) AS ?tot)
WHERE {
   # All four tourmamets in Grand Slam
   VALUES (?tournament){
       (wd:Q43605)  # French Open
       (wd:Q123577) # US Open
       (wd:Q41520)  # Wimbledon Championships
       (wd:Q60874)  # Australian Open
   }
   # ?yearlyTournament wdt:P31 ?tournament.
   # ?yearlyTournament wdt:P527 ?subTournament.
   # ?subTournament wdt:P1346 ?winner;
                   wdt:P2094 ?competitionClass.
   
   # ?winner wdt:P1532 ?countryForSport.
   
   # get the label 
   # ?tournament sc:name ?tournamentName .
   # ?yearlyTournament sc:name ?yearlyTournamentName .
   # ?subTournament sc:name ?subTournamentName.
   # ?winner sc:name ?winnerName.
   # ?competitionClass sc:name ?competitionClassName.
}
GROUP BY ?winner ?winnerName ?tournamentName
ORDER BY ?winnerName ?tot
LIMIT 100

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('winner', 'http://www.wikidata.org/entity/Q54668'), ('winnerName', 'Abigail Spears'), ('tournamentName', 'Australian Open'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q207352'), ('winnerName', 'Agnieszka Radwańska'), ('tournamentName', 'French Open'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q229100'), ('winnerName', 'Ai Sugiyama'), ('tournamentName', 'US Open'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q229100'), ('winnerName', 'Ai Sugiyama'), ('tournamentName', 'Wimbledon Championships'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q2712407'), ('winnerName', 'Ajla Tomljanović'), ('tournamentName', 'Australian Open'), ('tot', '2')]
# [('winner', 'http://www.wikidata.org/entity/Q317828'), ('winnerName', 'Albert Costa'), ('tournamentName', 'French Open'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q737425'), ('winnerName', "Alex O'Brien"), ('tournamentName', 'US Open'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q734544'), ('winnerName', 'Alex Olmedo'), ('tournamentName', 'Australian Open'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q734544'), ('winnerName', 'Alex Olmedo'), ('tournamentName', 'Wimbledon Championships'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q457476'), ('winnerName', 'Alexander Peya'), ('tournamentName', 'Wimbledon Championships'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q13990552'), ('winnerName', 'Alexander Zverev'), ('tournamentName', 'Australian Open'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q2834043'), ('winnerName', 'Alexandre Sidorenko'), ('tournamentName', 'Australian Open'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q333104'), ('winnerName', 'Aline Terry'), ('tournamentName', 'US Open'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q229002'), ('winnerName', 'Alizé Cornet'), ('tournamentName', 'French Open'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q231962'), ('winnerName', 'Alona Bondarenko'), ('tournamentName', 'Australian Open'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q53550'), ('winnerName', 'Althea Gibson'), ('tournamentName', 'French Open'), ('tot', '2')]
# [('winner', 'http://www.wikidata.org/entity/Q53550'), ('winnerName', 'Althea Gibson'), ('tournamentName', 'Wimbledon Championships'), ('tot', '5')]
# [('winner', 'http://www.wikidata.org/entity/Q24456716'), ('winnerName', 'Amanda Anisimova'), ('tournamentName', 'US Open'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q180872'), ('winnerName', 'Amélie Mauresmo'), ('tournamentName', 'Australian Open'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q180872'), ('winnerName', 'Amélie Mauresmo'), ('tournamentName', 'Wimbledon Championships'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q454683'), ('winnerName', 'An-Sophie Mestach'), ('tournamentName', 'Australian Open'), ('tot', '2')]
# [('winner', 'http://www.wikidata.org/entity/Q30758'), ('winnerName', 'Ana Ivanovic'), ('tournamentName', 'French Open'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q2365460'), ('winnerName', 'Ana Konjuh'), ('tournamentName', 'US Open'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q2365460'), ('winnerName', 'Ana Konjuh'), ('tournamentName', 'Australian Open'), ('tot', '2')]
# [('winner', 'http://www.wikidata.org/entity/Q219724'), ('winnerName', 'Anabel Medina Garrigues'), ('tournamentName', 'French Open'), ('tot', '2')]
# [('winner', 'http://www.wikidata.org/entity/Q203591'), ('winnerName', 'Anastasia Myskina'), ('tournamentName', 'French Open'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q487182'), ('winnerName', 'Anastasia Pavlyuchenkova'), ('tournamentName', 'Australian Open'), ('tot', '3')]
# [('winner', 'http://www.wikidata.org/entity/Q455136'), ('winnerName', 'Anders Järryd'), ('tournamentName', 'US Open'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q455136'), ('winnerName', 'Anders Järryd'), ('tournamentName', 'French Open'), ('tot', '3')]
# [('winner', 'http://www.wikidata.org/entity/Q455136'), ('winnerName', 'Anders Järryd'), ('tournamentName', 'Wimbledon Championships'), ('tot', '3')]
# [('winner', 'http://www.wikidata.org/entity/Q236648'), ('winnerName', 'Andrea Jaeger'), ('tournamentName', 'French Open'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q11581'), ('winnerName', 'Andrea Sestini Hlaváčková'), ('tournamentName', 'French Open'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q11581'), ('winnerName', 'Andrea Sestini Hlaváčková'), ('tournamentName', 'US Open'), ('tot', '2')]
# [('winner', 'http://www.wikidata.org/entity/Q18223058'), ('winnerName', 'Andreas Mies'), ('tournamentName', 'French Open'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q502583'), ('winnerName', 'Andrei Olhovskiy'), ('tournamentName', 'Australian Open'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q502583'), ('winnerName', 'Andrei Olhovskiy'), ('tournamentName', 'French Open'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q315958'), ('winnerName', 'Andrés Gimeno'), ('tournamentName', 'French Open'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q10125'), ('winnerName', 'Andy Murray'), ('tournamentName', 'Wimbledon Championships'), ('tot', '2')]
# [('winner', 'http://www.wikidata.org/entity/Q442632'), ('winnerName', 'Angela Buxton'), ('tournamentName', 'Wimbledon Championships'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q442632'), ('winnerName', 'Angela Buxton'), ('tournamentName', 'French Open'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q241727'), ('winnerName', 'Angela Mortimer'), ('tournamentName', 'Australian Open'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q241727'), ('winnerName', 'Angela Mortimer'), ('tournamentName', 'French Open'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q241727'), ('winnerName', 'Angela Mortimer'), ('tournamentName', 'Wimbledon Championships'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q77178'), ('winnerName', 'Angelique Kerber'), ('tournamentName', 'Wimbledon Championships'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q77178'), ('winnerName', 'Angelique Kerber'), ('tournamentName', 'Australian Open'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q77178'), ('winnerName', 'Angelique Kerber'), ('tournamentName', 'US Open'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q15642606'), ('winnerName', 'Anhelina Kalinina'), ('tournamentName', 'Australian Open'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q259356'), ('winnerName', 'Ann Haydon-Jones'), ('tournamentName', 'Australian Open'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q259356'), ('winnerName', 'Ann Haydon-Jones'), ('tournamentName', 'French Open'), ('tot', '3')]
# [('winner', 'http://www.wikidata.org/entity/Q458438'), ('winnerName', 'Ann Kiyomura'), ('tournamentName', 'Wimbledon Championships'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q20088944'), ('winnerName', 'Anna Kalinskaya'), ('tournamentName', 'Australian Open'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q131120'), ('winnerName', 'Anna Kournikova'), ('tournamentName', 'Australian Open'), ('tot', '2')]
# [('winner', 'http://www.wikidata.org/entity/Q57559'), ('winnerName', 'Anna-Lena Grönefeld'), ('tournamentName', 'Wimbledon Championships'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q57559'), ('winnerName', 'Anna-Lena Grönefeld'), ('tournamentName', 'French Open'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q270414'), ('winnerName', 'Anne Smith'), ('tournamentName', 'Australian Open'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q270414'), ('winnerName', 'Anne Smith'), ('tournamentName', 'Wimbledon Championships'), ('tot', '2')]
# [('winner', 'http://www.wikidata.org/entity/Q270414'), ('winnerName', 'Anne Smith'), ('tournamentName', 'US Open'), ('tot', '3')]
# [('winner', 'http://www.wikidata.org/entity/Q270414'), ('winnerName', 'Anne Smith'), ('tournamentName', 'French Open'), ('tot', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q77157'), ('winnerName', 'Annika Beck'), ('tournamentName', 'French Open'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q505788'), ('winnerName', 'Anthony Wilding'), ('tournamentName', 'Wimbledon Championships'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q505788'), ('winnerName', 'Anthony Wilding'), ('tournamentName', 'Australian Open'), ('tot', '2')]
# [('winner', 'http://www.wikidata.org/entity/Q188080'), ('winnerName', 'Arantxa Sánchez Vicario'), ('tournamentName', 'Wimbledon Championships'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q188080'), ('winnerName', 'Arantxa Sánchez Vicario'), ('tournamentName', 'US Open'), ('tot', '3')]
# [('winner', 'http://www.wikidata.org/entity/Q188080'), ('winnerName', 'Arantxa Sánchez Vicario'), ('tournamentName', 'Australian Open'), ('tot', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q188080'), ('winnerName', 'Arantxa Sánchez Vicario'), ('tournamentName', 'French Open'), ('tot', '5')]
# [('winner', 'http://www.wikidata.org/entity/Q291769'), ('winnerName', 'Arina Rodionova'), ('tournamentName', 'Australian Open'), ('tot', '2')]
# [('winner', 'http://www.wikidata.org/entity/Q299944'), ('winnerName', 'Arnaud Clément'), ('tournamentName', 'Wimbledon Championships'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q107207693'), ('winnerName', 'Arthur Fils'), ('tournamentName', 'French Open'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q84056'), ('winnerName', 'Ashleigh Barty'), ('tournamentName', 'French Open'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q84056'), ('winnerName', 'Ashleigh Barty'), ('tournamentName', 'Wimbledon Championships'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q84056'), ('winnerName', 'Ashleigh Barty'), ('tournamentName', 'US Open'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q370019'), ('winnerName', 'Balázs Taróczy'), ('tournamentName', 'French Open'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q53570'), ('winnerName', 'Barbara Jordan'), ('tournamentName', 'French Open'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q53570'), ('winnerName', 'Barbara Jordan'), ('tournamentName', 'Australian Open'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q11052500'), ('winnerName', 'Barbora Krejčíková'), ('tournamentName', 'US Open'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q11052500'), ('winnerName', 'Barbora Krejčíková'), ('tournamentName', 'Wimbledon Championships'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q11052500'), ('winnerName', 'Barbora Krejčíková'), ('tournamentName', 'Australian Open'), ('tot', '3')]
# [('winner', 'http://www.wikidata.org/entity/Q11052500'), ('winnerName', 'Barbora Krejčíková'), ('tournamentName', 'French Open'), ('tot', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q230353'), ('winnerName', 'Barbora Strýcová'), ('tournamentName', 'Wimbledon Championships'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q509903'), ('winnerName', 'Belinda Bencic'), ('tournamentName', 'French Open'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q288326'), ('winnerName', 'Bernard Tomic'), ('tournamentName', 'US Open'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q288326'), ('winnerName', 'Bernard Tomic'), ('tournamentName', 'Australian Open'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q453061'), ('winnerName', 'Bertha Townsend'), ('tournamentName', 'US Open'), ('tot', '2')]
# [('winner', 'http://www.wikidata.org/entity/Q54537'), ('winnerName', 'Bethanie Mattek-Sands'), ('tournamentName', 'French Open'), ('tot', '3')]
# [('winner', 'http://www.wikidata.org/entity/Q54537'), ('winnerName', 'Bethanie Mattek-Sands'), ('tournamentName', 'Australian Open'), ('tot', '3')]
# [('winner', 'http://www.wikidata.org/entity/Q54537'), ('winnerName', 'Bethanie Mattek-Sands'), ('tournamentName', 'US Open'), ('tot', '3')]
# [('winner', 'http://www.wikidata.org/entity/Q293082'), ('winnerName', 'Betsy Nagelsen'), ('tournamentName', 'Australian Open'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q259282'), ('winnerName', 'Betty Stöve'), ('tournamentName', 'Wimbledon Championships'), ('tot', '2')]
# [('winner', 'http://www.wikidata.org/entity/Q259282'), ('winnerName', 'Betty Stöve'), ('tournamentName', 'French Open'), ('tot', '2')]
# [('winner', 'http://www.wikidata.org/entity/Q259282'), ('winnerName', 'Betty Stöve'), ('tournamentName', 'US Open'), ('tot', '3')]
# [('winner', 'http://www.wikidata.org/entity/Q22957410'), ('winnerName', 'Bianca Andreescu'), ('tournamentName', 'US Open'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q54527'), ('winnerName', 'Billie Jean King'), ('tournamentName', 'US Open'), ('tot', '2')]
# [('winner', 'http://www.wikidata.org/entity/Q54527'), ('winnerName', 'Billie Jean King'), ('tournamentName', 'Australian Open'), ('tot', '2')]
# [('winner', 'http://www.wikidata.org/entity/Q54527'), ('winnerName', 'Billie Jean King'), ('tournamentName', 'French Open'), ('tot', '3')]
# [('winner', 'http://www.wikidata.org/entity/Q54527'), ('winnerName', 'Billie Jean King'), ('tournamentName', 'Wimbledon Championships'), ('tot', '5')]
# [('winner', 'http://www.wikidata.org/entity/Q2903676'), ('winnerName', 'Billy Martin'), ('tournamentName', 'French Open'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q104506'), ('winnerName', 'Björn Borg'), ('tournamentName', 'Wimbledon Championships'), ('tot', '5')]
# [('winner', 'http://www.wikidata.org/entity/Q104506'), ('winnerName', 'Björn Borg'), ('tournamentName', 'French Open'), ('tot', '5')]
# [('winner', 'http://www.wikidata.org/entity/Q273468'), ('winnerName', 'Blanche Bingley'), ('tournamentName', 'Wimbledon Championships'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q53420'), ('winnerName', 'Bob Falkenburg'), ('tournamentName', 'Wimbledon Championships'), ('tot', '1')]
# 100

# %%
# write your queries
# Consider the country for sport property of the tennis player (NO Country of citizenship). 
# Return the countries with at least one player who won at least one edition of each Grand Slam (the result set must be a list of country IRI and label).

# P31 ('instance of')
# P527 ('has part')
# P1346 ('winner')
# P1532 ('country for sport')

# GROUP BY ?winner & ?tournament
# ORDERING
# LIMIT extended to 100

# CREATING outer query


queryString = """

PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
SELECT * 
WHERE {
    SELECT DISTINCT ?winner ?winnerName ?tournamentName (COUNT(*) AS ?tot)
    WHERE {
       # All four tourmamets in Grand Slam
       VALUES (?tournament){
           (wd:Q43605)  # French Open
           (wd:Q123577) # US Open
           (wd:Q41520)  # Wimbledon Championships
           (wd:Q60874)  # Australian Open
       }
       # ?yearlyTournament wdt:P31 ?tournament.
       # ?yearlyTournament wdt:P527 ?subTournament.
       # ?subTournament wdt:P1346 ?winner;
                       wdt:P2094 ?competitionClass.

       # ?winner wdt:P1532 ?countryForSport.

       # get the label 
       # ?tournament sc:name ?tournamentName .
       # ?yearlyTournament sc:name ?yearlyTournamentName .
       # ?subTournament sc:name ?subTournamentName.
       # ?winner sc:name ?winnerName.
       # ?competitionClass sc:name ?competitionClassName.
    }
    GROUP BY ?winner ?winnerName ?tournamentName
    ORDER BY ?winnerName ?tot
}
LIMIT 100

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('winner', 'http://www.wikidata.org/entity/Q54668'), ('winnerName', 'Abigail Spears'), ('tournamentName', 'Australian Open'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q207352'), ('winnerName', 'Agnieszka Radwańska'), ('tournamentName', 'French Open'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q229100'), ('winnerName', 'Ai Sugiyama'), ('tournamentName', 'US Open'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q229100'), ('winnerName', 'Ai Sugiyama'), ('tournamentName', 'Wimbledon Championships'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q2712407'), ('winnerName', 'Ajla Tomljanović'), ('tournamentName', 'Australian Open'), ('tot', '2')]
# [('winner', 'http://www.wikidata.org/entity/Q317828'), ('winnerName', 'Albert Costa'), ('tournamentName', 'French Open'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q737425'), ('winnerName', "Alex O'Brien"), ('tournamentName', 'US Open'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q734544'), ('winnerName', 'Alex Olmedo'), ('tournamentName', 'Australian Open'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q734544'), ('winnerName', 'Alex Olmedo'), ('tournamentName', 'Wimbledon Championships'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q457476'), ('winnerName', 'Alexander Peya'), ('tournamentName', 'Wimbledon Championships'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q13990552'), ('winnerName', 'Alexander Zverev'), ('tournamentName', 'Australian Open'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q2834043'), ('winnerName', 'Alexandre Sidorenko'), ('tournamentName', 'Australian Open'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q333104'), ('winnerName', 'Aline Terry'), ('tournamentName', 'US Open'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q229002'), ('winnerName', 'Alizé Cornet'), ('tournamentName', 'French Open'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q231962'), ('winnerName', 'Alona Bondarenko'), ('tournamentName', 'Australian Open'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q53550'), ('winnerName', 'Althea Gibson'), ('tournamentName', 'French Open'), ('tot', '2')]
# [('winner', 'http://www.wikidata.org/entity/Q53550'), ('winnerName', 'Althea Gibson'), ('tournamentName', 'Wimbledon Championships'), ('tot', '5')]
# [('winner', 'http://www.wikidata.org/entity/Q24456716'), ('winnerName', 'Amanda Anisimova'), ('tournamentName', 'US Open'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q180872'), ('winnerName', 'Amélie Mauresmo'), ('tournamentName', 'Australian Open'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q180872'), ('winnerName', 'Amélie Mauresmo'), ('tournamentName', 'Wimbledon Championships'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q454683'), ('winnerName', 'An-Sophie Mestach'), ('tournamentName', 'Australian Open'), ('tot', '2')]
# [('winner', 'http://www.wikidata.org/entity/Q30758'), ('winnerName', 'Ana Ivanovic'), ('tournamentName', 'French Open'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q2365460'), ('winnerName', 'Ana Konjuh'), ('tournamentName', 'US Open'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q2365460'), ('winnerName', 'Ana Konjuh'), ('tournamentName', 'Australian Open'), ('tot', '2')]
# [('winner', 'http://www.wikidata.org/entity/Q219724'), ('winnerName', 'Anabel Medina Garrigues'), ('tournamentName', 'French Open'), ('tot', '2')]
# [('winner', 'http://www.wikidata.org/entity/Q203591'), ('winnerName', 'Anastasia Myskina'), ('tournamentName', 'French Open'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q487182'), ('winnerName', 'Anastasia Pavlyuchenkova'), ('tournamentName', 'Australian Open'), ('tot', '3')]
# [('winner', 'http://www.wikidata.org/entity/Q455136'), ('winnerName', 'Anders Järryd'), ('tournamentName', 'US Open'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q455136'), ('winnerName', 'Anders Järryd'), ('tournamentName', 'French Open'), ('tot', '3')]
# [('winner', 'http://www.wikidata.org/entity/Q455136'), ('winnerName', 'Anders Järryd'), ('tournamentName', 'Wimbledon Championships'), ('tot', '3')]
# [('winner', 'http://www.wikidata.org/entity/Q236648'), ('winnerName', 'Andrea Jaeger'), ('tournamentName', 'French Open'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q11581'), ('winnerName', 'Andrea Sestini Hlaváčková'), ('tournamentName', 'French Open'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q11581'), ('winnerName', 'Andrea Sestini Hlaváčková'), ('tournamentName', 'US Open'), ('tot', '2')]
# [('winner', 'http://www.wikidata.org/entity/Q18223058'), ('winnerName', 'Andreas Mies'), ('tournamentName', 'French Open'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q502583'), ('winnerName', 'Andrei Olhovskiy'), ('tournamentName', 'Australian Open'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q502583'), ('winnerName', 'Andrei Olhovskiy'), ('tournamentName', 'French Open'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q315958'), ('winnerName', 'Andrés Gimeno'), ('tournamentName', 'French Open'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q10125'), ('winnerName', 'Andy Murray'), ('tournamentName', 'Wimbledon Championships'), ('tot', '2')]
# [('winner', 'http://www.wikidata.org/entity/Q442632'), ('winnerName', 'Angela Buxton'), ('tournamentName', 'Wimbledon Championships'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q442632'), ('winnerName', 'Angela Buxton'), ('tournamentName', 'French Open'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q241727'), ('winnerName', 'Angela Mortimer'), ('tournamentName', 'Australian Open'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q241727'), ('winnerName', 'Angela Mortimer'), ('tournamentName', 'French Open'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q241727'), ('winnerName', 'Angela Mortimer'), ('tournamentName', 'Wimbledon Championships'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q77178'), ('winnerName', 'Angelique Kerber'), ('tournamentName', 'Wimbledon Championships'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q77178'), ('winnerName', 'Angelique Kerber'), ('tournamentName', 'Australian Open'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q77178'), ('winnerName', 'Angelique Kerber'), ('tournamentName', 'US Open'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q15642606'), ('winnerName', 'Anhelina Kalinina'), ('tournamentName', 'Australian Open'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q259356'), ('winnerName', 'Ann Haydon-Jones'), ('tournamentName', 'Australian Open'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q259356'), ('winnerName', 'Ann Haydon-Jones'), ('tournamentName', 'French Open'), ('tot', '3')]
# [('winner', 'http://www.wikidata.org/entity/Q458438'), ('winnerName', 'Ann Kiyomura'), ('tournamentName', 'Wimbledon Championships'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q20088944'), ('winnerName', 'Anna Kalinskaya'), ('tournamentName', 'Australian Open'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q131120'), ('winnerName', 'Anna Kournikova'), ('tournamentName', 'Australian Open'), ('tot', '2')]
# [('winner', 'http://www.wikidata.org/entity/Q57559'), ('winnerName', 'Anna-Lena Grönefeld'), ('tournamentName', 'Wimbledon Championships'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q57559'), ('winnerName', 'Anna-Lena Grönefeld'), ('tournamentName', 'French Open'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q270414'), ('winnerName', 'Anne Smith'), ('tournamentName', 'Australian Open'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q270414'), ('winnerName', 'Anne Smith'), ('tournamentName', 'Wimbledon Championships'), ('tot', '2')]
# [('winner', 'http://www.wikidata.org/entity/Q270414'), ('winnerName', 'Anne Smith'), ('tournamentName', 'US Open'), ('tot', '3')]
# [('winner', 'http://www.wikidata.org/entity/Q270414'), ('winnerName', 'Anne Smith'), ('tournamentName', 'French Open'), ('tot', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q77157'), ('winnerName', 'Annika Beck'), ('tournamentName', 'French Open'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q505788'), ('winnerName', 'Anthony Wilding'), ('tournamentName', 'Wimbledon Championships'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q505788'), ('winnerName', 'Anthony Wilding'), ('tournamentName', 'Australian Open'), ('tot', '2')]
# [('winner', 'http://www.wikidata.org/entity/Q188080'), ('winnerName', 'Arantxa Sánchez Vicario'), ('tournamentName', 'Wimbledon Championships'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q188080'), ('winnerName', 'Arantxa Sánchez Vicario'), ('tournamentName', 'US Open'), ('tot', '3')]
# [('winner', 'http://www.wikidata.org/entity/Q188080'), ('winnerName', 'Arantxa Sánchez Vicario'), ('tournamentName', 'Australian Open'), ('tot', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q188080'), ('winnerName', 'Arantxa Sánchez Vicario'), ('tournamentName', 'French Open'), ('tot', '5')]
# [('winner', 'http://www.wikidata.org/entity/Q291769'), ('winnerName', 'Arina Rodionova'), ('tournamentName', 'Australian Open'), ('tot', '2')]
# [('winner', 'http://www.wikidata.org/entity/Q299944'), ('winnerName', 'Arnaud Clément'), ('tournamentName', 'Wimbledon Championships'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q107207693'), ('winnerName', 'Arthur Fils'), ('tournamentName', 'French Open'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q84056'), ('winnerName', 'Ashleigh Barty'), ('tournamentName', 'French Open'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q84056'), ('winnerName', 'Ashleigh Barty'), ('tournamentName', 'Wimbledon Championships'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q84056'), ('winnerName', 'Ashleigh Barty'), ('tournamentName', 'US Open'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q370019'), ('winnerName', 'Balázs Taróczy'), ('tournamentName', 'French Open'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q53570'), ('winnerName', 'Barbara Jordan'), ('tournamentName', 'French Open'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q53570'), ('winnerName', 'Barbara Jordan'), ('tournamentName', 'Australian Open'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q11052500'), ('winnerName', 'Barbora Krejčíková'), ('tournamentName', 'US Open'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q11052500'), ('winnerName', 'Barbora Krejčíková'), ('tournamentName', 'Wimbledon Championships'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q11052500'), ('winnerName', 'Barbora Krejčíková'), ('tournamentName', 'Australian Open'), ('tot', '3')]
# [('winner', 'http://www.wikidata.org/entity/Q11052500'), ('winnerName', 'Barbora Krejčíková'), ('tournamentName', 'French Open'), ('tot', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q230353'), ('winnerName', 'Barbora Strýcová'), ('tournamentName', 'Wimbledon Championships'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q509903'), ('winnerName', 'Belinda Bencic'), ('tournamentName', 'French Open'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q288326'), ('winnerName', 'Bernard Tomic'), ('tournamentName', 'US Open'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q288326'), ('winnerName', 'Bernard Tomic'), ('tournamentName', 'Australian Open'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q453061'), ('winnerName', 'Bertha Townsend'), ('tournamentName', 'US Open'), ('tot', '2')]
# [('winner', 'http://www.wikidata.org/entity/Q54537'), ('winnerName', 'Bethanie Mattek-Sands'), ('tournamentName', 'French Open'), ('tot', '3')]
# [('winner', 'http://www.wikidata.org/entity/Q54537'), ('winnerName', 'Bethanie Mattek-Sands'), ('tournamentName', 'Australian Open'), ('tot', '3')]
# [('winner', 'http://www.wikidata.org/entity/Q54537'), ('winnerName', 'Bethanie Mattek-Sands'), ('tournamentName', 'US Open'), ('tot', '3')]
# [('winner', 'http://www.wikidata.org/entity/Q293082'), ('winnerName', 'Betsy Nagelsen'), ('tournamentName', 'Australian Open'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q259282'), ('winnerName', 'Betty Stöve'), ('tournamentName', 'Wimbledon Championships'), ('tot', '2')]
# [('winner', 'http://www.wikidata.org/entity/Q259282'), ('winnerName', 'Betty Stöve'), ('tournamentName', 'French Open'), ('tot', '2')]
# [('winner', 'http://www.wikidata.org/entity/Q259282'), ('winnerName', 'Betty Stöve'), ('tournamentName', 'US Open'), ('tot', '3')]
# [('winner', 'http://www.wikidata.org/entity/Q22957410'), ('winnerName', 'Bianca Andreescu'), ('tournamentName', 'US Open'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q54527'), ('winnerName', 'Billie Jean King'), ('tournamentName', 'US Open'), ('tot', '2')]
# [('winner', 'http://www.wikidata.org/entity/Q54527'), ('winnerName', 'Billie Jean King'), ('tournamentName', 'Australian Open'), ('tot', '2')]
# [('winner', 'http://www.wikidata.org/entity/Q54527'), ('winnerName', 'Billie Jean King'), ('tournamentName', 'French Open'), ('tot', '3')]
# [('winner', 'http://www.wikidata.org/entity/Q54527'), ('winnerName', 'Billie Jean King'), ('tournamentName', 'Wimbledon Championships'), ('tot', '5')]
# [('winner', 'http://www.wikidata.org/entity/Q2903676'), ('winnerName', 'Billy Martin'), ('tournamentName', 'French Open'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q104506'), ('winnerName', 'Björn Borg'), ('tournamentName', 'Wimbledon Championships'), ('tot', '5')]
# [('winner', 'http://www.wikidata.org/entity/Q104506'), ('winnerName', 'Björn Borg'), ('tournamentName', 'French Open'), ('tot', '5')]
# [('winner', 'http://www.wikidata.org/entity/Q273468'), ('winnerName', 'Blanche Bingley'), ('tournamentName', 'Wimbledon Championships'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q53420'), ('winnerName', 'Bob Falkenburg'), ('tournamentName', 'Wimbledon Championships'), ('tot', '1')]
# 100

# %%
# write your queries
# Consider the country for sport property of the tennis player (NO Country of citizenship). 
# Return the countries with at least one player who won at least one edition of each Grand Slam (the result set must be a list of country IRI and label).

# P31 ('instance of')
# P527 ('has part')
# P1346 ('winner')
# P1532 ('country for sport')

# GROUP BY ?winner & ?tournament
# ORDERING
# LIMIT extended to 100

# CREATING outer query


queryString = """

PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
SELECT ?winner ?winnerName ?tot
WHERE {
    SELECT DISTINCT ?winner ?winnerName ?tournamentName (COUNT(*) AS ?tot)
    WHERE {
       # All four tourmamets in Grand Slam
       VALUES (?tournament){
           (wd:Q43605)  # French Open
           (wd:Q123577) # US Open
           (wd:Q41520)  # Wimbledon Championships
           (wd:Q60874)  # Australian Open
       }
       # ?yearlyTournament wdt:P31 ?tournament.
       # ?yearlyTournament wdt:P527 ?subTournament.
       # ?subTournament wdt:P1346 ?winner;
                       wdt:P2094 ?competitionClass.

       # ?winner wdt:P1532 ?countryForSport.

       # get the label 
       # ?tournament sc:name ?tournamentName .
       # ?yearlyTournament sc:name ?yearlyTournamentName .
       # ?subTournament sc:name ?subTournamentName.
       # ?winner sc:name ?winnerName.
       # ?competitionClass sc:name ?competitionClassName.
    }
    GROUP BY ?winner ?winnerName ?tournamentName
    ORDER BY ?winnerName ?tot
}
GROUP BY ?winner ?winnerName
#ORDER BY DESC ?tot
LIMIT 100

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('winner', 'http://www.wikidata.org/entity/Q30758'), ('winnerName', 'Ana Ivanovic'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q2365460'), ('winnerName', 'Ana Konjuh'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q77178'), ('winnerName', 'Angelique Kerber'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q107207693'), ('winnerName', 'Arthur Fils'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q53570'), ('winnerName', 'Barbara Jordan'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q259282'), ('winnerName', 'Betty Stöve'), ('tot', '3')]
# [('winner', 'http://www.wikidata.org/entity/Q54527'), ('winnerName', 'Billie Jean King'), ('tot', '3')]
# [('winner', 'http://www.wikidata.org/entity/Q104506'), ('winnerName', 'Björn Borg'), ('tot', '5')]
# [('winner', 'http://www.wikidata.org/entity/Q888085'), ('winnerName', 'Bob Lutz'), ('tot', '3')]
# [('winner', 'http://www.wikidata.org/entity/Q14905846'), ('winnerName', 'Borna Ćorić'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q53555'), ('winnerName', 'Carly Gullickson'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q3702485'), ('winnerName', 'Carol Zhao'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q27537235'), ('winnerName', 'Caty McNally'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q5072631'), ('winnerName', 'Chantal Škamlová'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q14286'), ('winnerName', 'Chris Evert'), ('tot', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q62183'), ('winnerName', 'Cilly Aussem'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q61142'), ('winnerName', 'Claudia Kohde-Kilsch'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q232618'), ('winnerName', 'Conchita Martínez'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q233231'), ('winnerName', 'Elena Likhovtseva'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q270249'), ('winnerName', 'Elina Svitolina'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q5363900'), ('winnerName', 'Elizaveta Kulichkova'), ('tot', '2')]
# [('winner', 'http://www.wikidata.org/entity/Q429013'), ('winnerName', 'Emilio Sánchez'), ('tot', '2')]
# [('winner', 'http://www.wikidata.org/entity/Q64849968'), ('winnerName', 'Emma Raducanu'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q1381721'), ('winnerName', 'Evelyn Dearman'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q223695'), ('winnerName', 'Feliciano López'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q207528'), ('winnerName', 'Flavia Pennetta'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q469922'), ('winnerName', 'Frank Hadow'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q638555'), ('winnerName', 'Heinz Günthardt'), ('tot', '2')]
# [('winner', 'http://www.wikidata.org/entity/Q54543'), ('winnerName', 'Helen Wills'), ('tot', '3')]
# [('winner', 'http://www.wikidata.org/entity/Q13538'), ('winnerName', 'Henri Kontinen'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q230371'), ('winnerName', 'Iveta Melzer'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q715252'), ('winnerName', 'Jared Eisley Palmer'), ('tot', '2')]
# [('winner', 'http://www.wikidata.org/entity/Q53393'), ('winnerName', 'Jimmy Connors'), ('tot', '3')]
# [('winner', 'http://www.wikidata.org/entity/Q436562'), ('winnerName', 'Jo Durie'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q11682'), ('winnerName', 'Justine Henin'), ('tot', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q264493'), ('winnerName', 'Kathy Jordan'), ('tot', '2')]
# [('winner', 'http://www.wikidata.org/entity/Q608657'), ('winnerName', 'Ken Flach'), ('tot', '3')]
# [('winner', 'http://www.wikidata.org/entity/Q234624'), ('winnerName', 'Latisha Chan'), ('tot', '2')]
# [('winner', 'http://www.wikidata.org/entity/Q10129'), ('winnerName', 'Lisa Raymond'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q123298'), ('winnerName', 'Marc Rosset'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q18003204'), ('winnerName', 'Marie Bouzková'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q245241'), ('winnerName', 'Marin Čilić'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q1588571'), ('winnerName', 'Mate Pavić'), ('tot', '2')]
# [('winner', 'http://www.wikidata.org/entity/Q221359'), ('winnerName', 'Max Mirnyi'), ('tot', '2')]
# [('winner', 'http://www.wikidata.org/entity/Q6835083'), ('winnerName', 'Michael Venus'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q233243'), ('winnerName', 'Natasha Zvereva'), ('tot', '5')]
# [('winner', 'http://www.wikidata.org/entity/Q709909'), ('winnerName', 'Nicola Pietrangeli'), ('tot', '2')]
# [('winner', 'http://www.wikidata.org/entity/Q273472'), ('winnerName', 'Patty Fendick'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q972727'), ('winnerName', 'Raúl Ramírez'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q715130'), ('winnerName', 'Rick Leach'), ('tot', '5')]
# [('winner', 'http://www.wikidata.org/entity/Q511986'), ('winnerName', 'Rohan Bopanna'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q18637944'), ('winnerName', 'Roman Safiullin'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q913885'), ('winnerName', 'Sergio Casal'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q315970'), ('winnerName', 'Simone Bolelli'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q469884'), ('winnerName', 'Spencer Gore'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q11662'), ('winnerName', 'Steffi Graf'), ('tot', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q239765'), ('winnerName', 'Tímea Babos'), ('tot', '3')]
# [('winner', 'http://www.wikidata.org/entity/Q247192'), ('winnerName', 'Valeriya Solovyeva'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q11578'), ('winnerName', 'Venus Williams'), ('tot', '5')]
# [('winner', 'http://www.wikidata.org/entity/Q54668'), ('winnerName', 'Abigail Spears'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q229100'), ('winnerName', 'Ai Sugiyama'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q180872'), ('winnerName', 'Amélie Mauresmo'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q2365460'), ('winnerName', 'Ana Konjuh'), ('tot', '2')]
# [('winner', 'http://www.wikidata.org/entity/Q15642606'), ('winnerName', 'Anhelina Kalinina'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q188080'), ('winnerName', 'Arantxa Sánchez Vicario'), ('tot', '5')]
# [('winner', 'http://www.wikidata.org/entity/Q299944'), ('winnerName', 'Arnaud Clément'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q54537'), ('winnerName', 'Bethanie Mattek-Sands'), ('tot', '3')]
# [('winner', 'http://www.wikidata.org/entity/Q30767'), ('winnerName', 'Caroline Wozniacki'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q225589'), ('winnerName', 'Corina Morariu'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q298542'), ('winnerName', 'Daniel Nestor'), ('tot', '3')]
# [('winner', 'http://www.wikidata.org/entity/Q65553008'), ('winnerName', 'Daria Snigur'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q53564'), ('winnerName', 'Doris Hart'), ('tot', '3')]
# [('winner', 'http://www.wikidata.org/entity/Q228559'), ('winnerName', 'Evonne Goolagong Cawley'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q312726'), ('winnerName', 'Fabrice Santoro'), ('tot', '2')]
# [('winner', 'http://www.wikidata.org/entity/Q263134'), ('winnerName', 'Françoise Dürr'), ('tot', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q2760368'), ('winnerName', 'Gene Mayer'), ('tot', '2')]
# [('winner', 'http://www.wikidata.org/entity/Q233332'), ('winnerName', 'Gigi Fernández'), ('tot', '2')]
# [('winner', 'http://www.wikidata.org/entity/Q337681'), ('winnerName', 'Grigor Dimitrov'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q255011'), ('winnerName', 'Hana Mandlíková'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q5924232'), ('winnerName', 'Hsieh Cheng-peng'), ('tot', '2')]
# [('winner', 'http://www.wikidata.org/entity/Q18580128'), ('winnerName', 'Joe Salisbury'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q264493'), ('winnerName', 'Kathy Jordan'), ('tot', '3')]
# [('winner', 'http://www.wikidata.org/entity/Q439942'), ('winnerName', 'Marcelo Melo'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q447885'), ('winnerName', 'Margaret Scriven'), ('tot', '2')]
# [('winner', 'http://www.wikidata.org/entity/Q233247'), ('winnerName', 'Maria Bueno'), ('tot', '3')]
# [('winner', 'http://www.wikidata.org/entity/Q11666'), ('winnerName', 'Maria Sharapova'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q54545'), ('winnerName', 'Martina Navratilova'), ('tot', '30')]
# [('winner', 'http://www.wikidata.org/entity/Q1588571'), ('winnerName', 'Mate Pavić'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q233243'), ('winnerName', 'Natasha Zvereva'), ('tot', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q317974'), ('winnerName', 'Nicolas Mahut'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q7035585'), ('winnerName', 'Nikola Mektić'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q5812'), ('winnerName', 'Novak Djokovic'), ('tot', '9')]
# [('winner', 'http://www.wikidata.org/entity/Q963083'), ('winnerName', 'Oliver Campbell'), ('tot', '3')]
# [('winner', 'http://www.wikidata.org/entity/Q552626'), ('winnerName', 'Pat Hughes'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q1426'), ('winnerName', 'Roger Federer'), ('tot', '6')]
# [('winner', 'http://www.wikidata.org/entity/Q53326'), ('winnerName', 'Tracy Austin'), ('tot', '2')]
# [('winner', 'http://www.wikidata.org/entity/Q44465805'), ('winnerName', 'Wang Xinyu'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q28137186'), ('winnerName', 'Wu Yibing'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q231962'), ('winnerName', 'Alona Bondarenko'), ('tot', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q455136'), ('winnerName', 'Anders Järryd'), ('tot', '1')]
# 100

# %%
# write your queries
# Consider the country for sport property of the tennis player (NO Country of citizenship). 
# Return the countries with at least one player who won at least one edition of each Grand Slam (the result set must be a list of country IRI and label).

# P31 ('instance of')
# P527 ('has part')
# P1346 ('winner')
# P1532 ('country for sport')

# GROUP BY ?winner & ?tournament
# ORDERING
# LIMIT extended to 100

# CREATING outer query -> prob result is incorrect, it should have atmost 4 as there are only 4 tournaments possible but 
#                         it is keeping only one row for each player from inner query

# TRYING to debug with one player specifically ('Natasha Zvereva')


queryString = """

PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
SELECT *
WHERE {
    {
        SELECT DISTINCT ?winner ?winnerName ?tournamentName (COUNT(*) AS ?tot)
        WHERE {
           # All four tourmamets in Grand Slam
           VALUES (?tournament){
               (wd:Q43605)  # French Open
               (wd:Q123577) # US Open
               (wd:Q41520)  # Wimbledon Championships
               (wd:Q60874)  # Australian Open
           }
           # ?yearlyTournament wdt:P31 ?tournament.
           # ?yearlyTournament wdt:P527 ?subTournament.
           # ?subTournament wdt:P1346 ?winner;
                           wdt:P2094 ?competitionClass.

           # ?winner wdt:P1532 ?countryForSport.

           # get the label 
           # ?tournament sc:name ?tournamentName .
           # ?yearlyTournament sc:name ?yearlyTournamentName .
           # ?subTournament sc:name ?subTournamentName.
           # ?winner sc:name ?winnerName.
           # ?competitionClass sc:name ?competitionClassName.
        }
        GROUP BY ?winner ?winnerName ?tournamentName
        ORDER BY ?winnerName ?tot
    }
    FILTER (?winnerName = "Natasha Zvereva")
}
#GROUP BY ?winner ?winnerName
#ORDER BY DESC ?tot
LIMIT 100

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# Empty

# %% [markdown]
# ##### Cool query: founds all winning of a player in each tournament

# %%
# write your queries
# Consider the country for sport property of the tennis player (NO Country of citizenship). 
# Return the countries with at least one player who won at least one edition of each Grand Slam (the result set must be a list of country IRI and label).

# P31 ('instance of')
# P527 ('has part')
# P1346 ('winner')
# P1532 ('country for sport')

# GROUP BY ?winner & ?tournament
# ORDERING
# LIMIT extended to 100

# CREATING outer query -> prob result is incorrect, it should have atmost 4 as there are only 4 tournaments possible but 
#                         it is keeping only one row for each player from inner query

# TRYING to debug with one player specifically ('Natasha Zvereva')
# FILTER with wrong parametes, added regex


queryString = """

PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
SELECT *
WHERE {
    {
        SELECT DISTINCT ?winner ?winnerName ?tournamentName (COUNT(*) AS ?tot)
        WHERE {
           # All four tourmamets in Grand Slam
           VALUES (?tournament){
               (wd:Q43605)  # French Open
               (wd:Q123577) # US Open
               (wd:Q41520)  # Wimbledon Championships
               (wd:Q60874)  # Australian Open
           }
           # ?yearlyTournament wdt:P31 ?tournament.
           # ?yearlyTournament wdt:P527 ?subTournament.
           # ?subTournament wdt:P1346 ?winner;
                           wdt:P2094 ?competitionClass.

           # ?winner wdt:P1532 ?countryForSport.

           # get the label 
           # ?tournament sc:name ?tournamentName .
           # ?yearlyTournament sc:name ?yearlyTournamentName .
           # ?subTournament sc:name ?subTournamentName.
           # ?winner sc:name ?winnerName.
           # ?competitionClass sc:name ?competitionClassName.
        }
        GROUP BY ?winner ?winnerName ?tournamentName
        ORDER BY ?winnerName ?tot
    }
    FILTER (regex(?winnerName,"Natasha Zvereva"))
}
#GROUP BY ?winner ?winnerName
#ORDER BY DESC ?tot
LIMIT 100

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('winner', 'http://www.wikidata.org/entity/Q233243'), ('winnerName', 'Natasha Zvereva'), ('tournamentName', 'US Open'), ('tot', '2')]
# [('winner', 'http://www.wikidata.org/entity/Q233243'), ('winnerName', 'Natasha Zvereva'), ('tournamentName', 'French Open'), ('tot', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q233243'), ('winnerName', 'Natasha Zvereva'), ('tournamentName', 'Australian Open'), ('tot', '5')]
# [('winner', 'http://www.wikidata.org/entity/Q233243'), ('winnerName', 'Natasha Zvereva'), ('tournamentName', 'Wimbledon Championships'), ('tot', '5')]
# 4

# %%
# write your queries
# Consider the country for sport property of the tennis player (NO Country of citizenship). 
# Return the countries with at least one player who won at least one edition of each Grand Slam (the result set must be a list of country IRI and label).

# P31 ('instance of')
# P527 ('has part')
# P1346 ('winner')
# P1532 ('country for sport')

# GROUP BY ?winner & ?tournament
# ORDERING
# LIMIT extended to 100

# CREATING outer query -> prob result is incorrect, it should have atmost 4 as there are only 4 tournaments possible but 
#                         it is keeping only one row for each player from inner query

# TRYING to debug with one player specifically ('Natasha Zvereva')
# FILTER with wrong parametes, added regex

# FIND, I need to group also in the outer select


queryString = """

PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
SELECT ?winner ?winnerName (count(*) as ?all)
WHERE {
    {
        SELECT DISTINCT ?winner ?winnerName ?tournamentName (COUNT(*) AS ?tot)
        WHERE {
           # All four tourmamets in Grand Slam
           VALUES (?tournament){
               (wd:Q43605)  # French Open
               (wd:Q123577) # US Open
               (wd:Q41520)  # Wimbledon Championships
               (wd:Q60874)  # Australian Open
           }
           # ?yearlyTournament wdt:P31 ?tournament.
           # ?yearlyTournament wdt:P527 ?subTournament.
           # ?subTournament wdt:P1346 ?winner;
                           wdt:P2094 ?competitionClass.

           # ?winner wdt:P1532 ?countryForSport.

           # get the label 
           # ?tournament sc:name ?tournamentName .
           # ?yearlyTournament sc:name ?yearlyTournamentName .
           # ?subTournament sc:name ?subTournamentName.
           # ?winner sc:name ?winnerName.
           # ?competitionClass sc:name ?competitionClassName.
        }
        GROUP BY ?winner ?winnerName ?tournamentName
        ORDER BY ?winnerName ?tot
    }
    FILTER (regex(?winnerName,"Natasha Zvereva"))
}
GROUP BY ?winner ?winnerName
ORDER BY desc (?all)
LIMIT 100

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('winner', 'http://www.wikidata.org/entity/Q233243'), ('winnerName', 'Natasha Zvereva'), ('all', '4')]
# 1

# %%
# write your queries
# Consider the country for sport property of the tennis player (NO Country of citizenship). 
# Return the countries with at least one player who won at least one edition of each Grand Slam (the result set must be a list of country IRI and label).

# P31 ('instance of')
# P527 ('has part')
# P1346 ('winner')
# P1532 ('country for sport')

# GROUP BY ?winner & ?tournament
# ORDERING
# LIMIT extended to 100

# CREATING outer query -> prob result is incorrect, it should have atmost 4 as there are only 4 tournaments possible but 
#                         it is keeping only one row for each player from inner query

# TRYING to debug with one player specifically ('Natasha Zvereva')
# FILTER with wrong parametes, added regex

# FIND, I need to group also in the outer select


queryString = """

PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
SELECT ?winner ?winnerName (count(*) as ?all)
WHERE {
    {
        SELECT DISTINCT ?winner ?winnerName ?tournamentName (COUNT(*) AS ?tot)
        WHERE {
           # All four tourmamets in Grand Slam
           VALUES (?tournament){
               (wd:Q43605)  # French Open
               (wd:Q123577) # US Open
               (wd:Q41520)  # Wimbledon Championships
               (wd:Q60874)  # Australian Open
           }
           # ?yearlyTournament wdt:P31 ?tournament.
           # ?yearlyTournament wdt:P527 ?subTournament.
           # ?subTournament wdt:P1346 ?winner;
                           wdt:P2094 ?competitionClass.

           # ?winner wdt:P1532 ?countryForSport.

           # get the label 
           # ?tournament sc:name ?tournamentName .
           # ?yearlyTournament sc:name ?yearlyTournamentName .
           # ?subTournament sc:name ?subTournamentName.
           # ?winner sc:name ?winnerName.
           # ?competitionClass sc:name ?competitionClassName.
        }
        GROUP BY ?winner ?winnerName ?tournamentName
        ORDER BY ?winnerName ?tot
    }
    #FILTER (regex(?winnerName,"Natasha Zvereva"))
}
GROUP BY ?winner ?winnerName
ORDER BY desc (?all)
LIMIT 100

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('winner', 'http://www.wikidata.org/entity/Q188080'), ('winnerName', 'Arantxa Sánchez Vicario'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q264493'), ('winnerName', 'Kathy Jordan'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q233243'), ('winnerName', 'Natasha Zvereva'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q132147'), ('winnerName', 'Sania Mirza'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q233332'), ('winnerName', 'Gigi Fernández'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q233247'), ('winnerName', 'Maria Bueno'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q14286'), ('winnerName', 'Chris Evert'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q11685'), ('winnerName', 'Kim Clijsters'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q11578'), ('winnerName', 'Venus Williams'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q10132'), ('winnerName', 'Rafael Nadal'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q426049'), ('winnerName', 'John Fitzgerald'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q134720'), ('winnerName', 'Martina Hingis'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q5812'), ('winnerName', 'Novak Djokovic'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q11459'), ('winnerName', 'Serena Williams'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q16224602'), ('winnerName', 'Yui Kamiji'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q296282'), ('winnerName', 'Leander Paes'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q11677'), ('winnerName', 'Lindsay Davenport'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q54545'), ('winnerName', 'Martina Navratilova'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q2093033'), ('winnerName', 'Pierre-Hugues Herbert'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q634844'), ('winnerName', 'Elena Vesnina'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q11052500'), ('winnerName', 'Barbora Krejčíková'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q54527'), ('winnerName', 'Billie Jean King'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q229151'), ('winnerName', 'Helena Suková'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q229121'), ('winnerName', 'Jana Novotná'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q1426'), ('winnerName', 'Roger Federer'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q54654'), ('winnerName', 'Pam Shriver'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q11662'), ('winnerName', 'Steffi Graf'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q270414'), ('winnerName', 'Anne Smith'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q255011'), ('winnerName', 'Hana Mandlíková'), ('all', '3')]
# [('winner', 'http://www.wikidata.org/entity/Q228989'), ('winnerName', 'Lucie Šafářová'), ('all', '3')]
# [('winner', 'http://www.wikidata.org/entity/Q16475'), ('winnerName', 'Mats Wilander'), ('all', '3')]
# [('winner', 'http://www.wikidata.org/entity/Q54537'), ('winnerName', 'Bethanie Mattek-Sands'), ('all', '3')]
# [('winner', 'http://www.wikidata.org/entity/Q317820'), ('winnerName', 'Jamie Murray'), ('all', '3')]
# [('winner', 'http://www.wikidata.org/entity/Q1289530'), ('winnerName', 'Marty Riessen'), ('all', '3')]
# [('winner', 'http://www.wikidata.org/entity/Q241727'), ('winnerName', 'Angela Mortimer'), ('all', '3')]
# [('winner', 'http://www.wikidata.org/entity/Q228559'), ('winnerName', 'Evonne Goolagong Cawley'), ('all', '3')]
# [('winner', 'http://www.wikidata.org/entity/Q60980388'), ('winnerName', 'Jonáš Forejtek'), ('all', '3')]
# [('winner', 'http://www.wikidata.org/entity/Q6277349'), ('winnerName', 'Jordanne Whiley'), ('all', '3')]
# [('winner', 'http://www.wikidata.org/entity/Q229005'), ('winnerName', 'Sara Errani'), ('all', '3')]
# [('winner', 'http://www.wikidata.org/entity/Q229093'), ('winnerName', 'Virginia Ruano Pascual'), ('all', '3')]
# [('winner', 'http://www.wikidata.org/entity/Q298542'), ('winnerName', 'Daniel Nestor'), ('all', '3')]
# [('winner', 'http://www.wikidata.org/entity/Q953688'), ('winnerName', 'Ekaterina Valeryevna Makarova'), ('all', '3')]
# [('winner', 'http://www.wikidata.org/entity/Q242959'), ('winnerName', 'Kristina Mladenovic'), ('all', '3')]
# [('winner', 'http://www.wikidata.org/entity/Q11666'), ('winnerName', 'Maria Sharapova'), ('all', '3')]
# [('winner', 'http://www.wikidata.org/entity/Q53390'), ('winnerName', 'Maureen Connolly'), ('all', '3')]
# [('winner', 'http://www.wikidata.org/entity/Q53424'), ('winnerName', 'Shirley Fry'), ('all', '3')]
# [('winner', 'http://www.wikidata.org/entity/Q239765'), ('winnerName', 'Tímea Babos'), ('all', '3')]
# [('winner', 'http://www.wikidata.org/entity/Q310380'), ('winnerName', 'Jonas Björkman'), ('all', '3')]
# [('winner', 'http://www.wikidata.org/entity/Q312554'), ('winnerName', 'Mahesh Bhupathi'), ('all', '3')]
# [('winner', 'http://www.wikidata.org/entity/Q173633'), ('winnerName', 'Monica Seles'), ('all', '3')]
# [('winner', 'http://www.wikidata.org/entity/Q233234'), ('winnerName', 'Virginia Wade'), ('all', '3')]
# [('winner', 'http://www.wikidata.org/entity/Q52430'), ('winnerName', 'Daniela Hantuchová'), ('all', '3')]
# [('winner', 'http://www.wikidata.org/entity/Q53564'), ('winnerName', 'Doris Hart'), ('all', '3')]
# [('winner', 'http://www.wikidata.org/entity/Q182736'), ('winnerName', 'Ivan Lendl'), ('all', '3')]
# [('winner', 'http://www.wikidata.org/entity/Q53393'), ('winnerName', 'Jimmy Connors'), ('all', '3')]
# [('winner', 'http://www.wikidata.org/entity/Q16474'), ('winnerName', 'John McEnroe'), ('all', '3')]
# [('winner', 'http://www.wikidata.org/entity/Q921488'), ('winnerName', 'Juan Sebastián Cabal'), ('all', '3')]
# [('winner', 'http://www.wikidata.org/entity/Q240695'), ('winnerName', 'Larisa Neiland'), ('all', '3')]
# [('winner', 'http://www.wikidata.org/entity/Q455136'), ('winnerName', 'Anders Järryd'), ('all', '3')]
# [('winner', 'http://www.wikidata.org/entity/Q84056'), ('winnerName', 'Ashleigh Barty'), ('all', '3')]
# [('winner', 'http://www.wikidata.org/entity/Q17381675'), ('winnerName', 'Elise Mertens'), ('all', '3')]
# [('winner', 'http://www.wikidata.org/entity/Q105550'), ('winnerName', 'Rod Laver'), ('all', '3')]
# [('winner', 'http://www.wikidata.org/entity/Q189542'), ('winnerName', 'Stefan Edberg'), ('all', '3')]
# [('winner', 'http://www.wikidata.org/entity/Q207705'), ('winnerName', 'Yevgeny Kafelnikov'), ('all', '3')]
# [('winner', 'http://www.wikidata.org/entity/Q53565'), ('winnerName', 'Liezel Huber'), ('all', '3')]
# [('winner', 'http://www.wikidata.org/entity/Q229116'), ('winnerName', 'Katarina Srebotnik'), ('all', '3')]
# [('winner', 'http://www.wikidata.org/entity/Q10129'), ('winnerName', 'Lisa Raymond'), ('all', '3')]
# [('winner', 'http://www.wikidata.org/entity/Q210695'), ('winnerName', 'Mary Pierce'), ('all', '3')]
# [('winner', 'http://www.wikidata.org/entity/Q193661'), ('winnerName', 'Stan Wawrinka'), ('all', '3')]
# [('winner', 'http://www.wikidata.org/entity/Q259282'), ('winnerName', 'Betty Stöve'), ('all', '3')]
# [('winner', 'http://www.wikidata.org/entity/Q234624'), ('winnerName', 'Latisha Chan'), ('all', '3')]
# [('winner', 'http://www.wikidata.org/entity/Q291677'), ('winnerName', 'Manon Bollegraf'), ('all', '3')]
# [('winner', 'http://www.wikidata.org/entity/Q317974'), ('winnerName', 'Nicolas Mahut'), ('all', '3')]
# [('winner', 'http://www.wikidata.org/entity/Q77178'), ('winnerName', 'Angelique Kerber'), ('all', '3')]
# [('winner', 'http://www.wikidata.org/entity/Q324515'), ('winnerName', 'Ivan Dodig'), ('all', '3')]
# [('winner', 'http://www.wikidata.org/entity/Q1588571'), ('winnerName', 'Mate Pavić'), ('all', '3')]
# [('winner', 'http://www.wikidata.org/entity/Q715130'), ('winnerName', 'Rick Leach'), ('all', '3')]
# [('winner', 'http://www.wikidata.org/entity/Q192064'), ('winnerName', 'Svetlana Kuznetsova'), ('all', '3')]
# [('winner', 'http://www.wikidata.org/entity/Q374053'), ('winnerName', 'Vera Zvonareva'), ('all', '3')]
# [('winner', 'http://www.wikidata.org/entity/Q53550'), ('winnerName', 'Althea Gibson'), ('all', '2')]
# [('winner', 'http://www.wikidata.org/entity/Q2365460'), ('winnerName', 'Ana Konjuh'), ('all', '2')]
# [('winner', 'http://www.wikidata.org/entity/Q34115005'), ('winnerName', 'Desirae Krawczyk'), ('all', '2')]
# [('winner', 'http://www.wikidata.org/entity/Q233231'), ('winnerName', 'Elena Likhovtseva'), ('all', '2')]
# [('winner', 'http://www.wikidata.org/entity/Q239605'), ('winnerName', 'Heather Watson'), ('all', '2')]
# [('winner', 'http://www.wikidata.org/entity/Q3720044'), ('winnerName', 'Kateřina Siniaková'), ('all', '2')]
# [('winner', 'http://www.wikidata.org/entity/Q41799108'), ('winnerName', 'Wang Xiyu'), ('all', '2')]
# [('winner', 'http://www.wikidata.org/entity/Q233221'), ('winnerName', 'Yan Zi'), ('all', '2')]
# [('winner', 'http://www.wikidata.org/entity/Q197639'), ('winnerName', 'Zheng Jie'), ('all', '2')]
# [('winner', 'http://www.wikidata.org/entity/Q2446649'), ('winnerName', 'Daria Gavrilova'), ('all', '2')]
# [('winner', 'http://www.wikidata.org/entity/Q53562'), ('winnerName', 'Darlene Hard'), ('all', '2')]
# [('winner', 'http://www.wikidata.org/entity/Q5515953'), ('winnerName', 'Gabriela Dabrowski'), ('all', '2')]
# [('winner', 'http://www.wikidata.org/entity/Q638555'), ('winnerName', 'Heinz Günthardt'), ('all', '2')]
# [('winner', 'http://www.wikidata.org/entity/Q1360272'), ('winnerName', 'John Lloyd'), ('all', '2')]
# [('winner', 'http://www.wikidata.org/entity/Q11682'), ('winnerName', 'Justine Henin'), ('all', '2')]
# [('winner', 'http://www.wikidata.org/entity/Q439942'), ('winnerName', 'Marcelo Melo'), ('all', '2')]
# [('winner', 'http://www.wikidata.org/entity/Q984213'), ('winnerName', 'Sherwood Stewart'), ('all', '2')]
# [('winner', 'http://www.wikidata.org/entity/Q502583'), ('winnerName', 'Andrei Olhovskiy'), ('all', '2')]
# [('winner', 'http://www.wikidata.org/entity/Q288326'), ('winnerName', 'Bernard Tomic'), ('all', '2')]
# [('winner', 'http://www.wikidata.org/entity/Q104506'), ('winnerName', 'Björn Borg'), ('all', '2')]
# [('winner', 'http://www.wikidata.org/entity/Q39263365'), ('winnerName', 'Cori Gauff'), ('all', '2')]
# 100

# %%
# write your queries
# Consider the country for sport property of the tennis player (NO Country of citizenship). 
# Return the countries with at least one player who won at least one edition of each Grand Slam (the result set must be a list of country IRI and label).

# P31 ('instance of')
# P527 ('has part')
# P1346 ('winner')
# P1532 ('country for sport')

# GROUP BY ?winner & ?tournament
# ORDERING
# LIMIT extended to 100

# CREATING outer query -> prob result is incorrect, it should have atmost 4 as there are only 4 tournaments possible but 
#                         it is keeping only one row for each player from inner query
# TRYING to debug with one player specifically ('Natasha Zvereva')
# FILTER with wrong parametes, added regex
# FIND, I need to group also in the outer select

# Checking correctness, ORDER BY 


queryString = """

PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
SELECT ?winner ?winnerName (count(*) as ?all)
WHERE {
    {
        SELECT DISTINCT ?winner ?winnerName ?tournamentName (COUNT(*) AS ?tot)
        WHERE {
           # All four tourmamets in Grand Slam
           VALUES (?tournament){
               (wd:Q43605)  # French Open
               (wd:Q123577) # US Open
               (wd:Q41520)  # Wimbledon Championships
               (wd:Q60874)  # Australian Open
           }
           # ?yearlyTournament wdt:P31 ?tournament.
           # ?yearlyTournament wdt:P527 ?subTournament.
           # ?subTournament wdt:P1346 ?winner;
                           wdt:P2094 ?competitionClass.

           # ?winner wdt:P1532 ?countryForSport.

           # get the label 
           # ?tournament sc:name ?tournamentName .
           # ?yearlyTournament sc:name ?yearlyTournamentName .
           # ?subTournament sc:name ?subTournamentName.
           # ?winner sc:name ?winnerName.
           # ?competitionClass sc:name ?competitionClassName.
        }
        GROUP BY ?winner ?winnerName ?tournamentName
        ORDER BY ?winnerName ?tot
    }
    #FILTER (regex(?winnerName,"Natasha Zvereva"))
}
GROUP BY ?winner ?winnerName
ORDER BY asc (?all)
LIMIT 100

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('winner', 'http://www.wikidata.org/entity/Q207352'), ('winnerName', 'Agnieszka Radwańska'), ('all', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q457476'), ('winnerName', 'Alexander Peya'), ('all', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q219724'), ('winnerName', 'Anabel Medina Garrigues'), ('all', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q458438'), ('winnerName', 'Ann Kiyomura'), ('all', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q273468'), ('winnerName', 'Blanche Bingley'), ('all', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q27537235'), ('winnerName', 'Caty McNally'), ('all', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q237894'), ('winnerName', 'Chanda Rubin'), ('all', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q54688'), ('winnerName', 'Coco Vandeweghe'), ('all', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q5363900'), ('winnerName', 'Elizaveta Kulichkova'), ('all', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q312726'), ('winnerName', 'Fabrice Santoro'), ('all', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q1452382'), ('winnerName', 'Frederick Hovey'), ('all', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q2760368'), ('winnerName', 'Gene Mayer'), ('all', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q715252'), ('winnerName', 'Jared Eisley Palmer'), ('all', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q232613'), ('winnerName', 'Ksenia Pervak'), ('all', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q89128'), ('winnerName', 'Laura Siegemund'), ('all', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q2965183'), ('winnerName', 'Liam Broady'), ('all', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q1892978'), ('winnerName', 'Marcel Bernard'), ('all', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q312717'), ('winnerName', 'Petr Korda'), ('all', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q369247'), ('winnerName', 'Robert Lindstedt'), ('all', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q511986'), ('winnerName', 'Rohan Bopanna'), ('all', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q53398'), ('winnerName', 'Samantha Crawford'), ('all', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q233256'), ('winnerName', 'Tatiana Golovin'), ('all', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q139645'), ('winnerName', 'Ulf Schmidt'), ('all', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q247192'), ('winnerName', 'Valeriya Solovyeva'), ('all', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q18965287'), ('winnerName', 'Vera Lapko'), ('all', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q239647'), ('winnerName', 'Virginia Ruzici'), ('all', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q333104'), ('winnerName', 'Aline Terry'), ('all', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q131120'), ('winnerName', 'Anna Kournikova'), ('all', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q107207693'), ('winnerName', 'Arthur Fils'), ('all', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q912255'), ('winnerName', 'Brian Gottfried'), ('all', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q229090'), ('winnerName', 'Casey Dellacqua'), ('all', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q5072631'), ('winnerName', 'Chantal Škamlová'), ('all', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q5240764'), ('winnerName', 'David Wagner'), ('all', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q2626148'), ('winnerName', 'Elena Bogdan'), ('all', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q67186609'), ('winnerName', 'Eliot Spizzirri'), ('all', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q467237'), ('winnerName', 'Elisabeth Moore'), ('all', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q64849968'), ('winnerName', 'Emma Raducanu'), ('all', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q223695'), ('winnerName', 'Feliciano López'), ('all', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q5448480'), ('winnerName', 'Filip Horanský'), ('all', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q188107'), ('winnerName', 'Francesca Schiavone'), ('all', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q1566777'), ('winnerName', 'Hans Simonsson'), ('all', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q538191'), ('winnerName', 'John Hartley'), ('all', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q241320'), ('winnerName', 'Julie Halard-Decugis'), ('all', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q231974'), ('winnerName', 'Kateryna Bondarenko'), ('all', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q521418'), ('winnerName', 'Leoš Friedl'), ('all', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q710611'), ('winnerName', 'Major Ritchie'), ('all', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q295488'), ('winnerName', 'Michaël Llodra'), ('all', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q358651'), ('winnerName', 'Pablo Cuevas'), ('all', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q53331'), ('winnerName', 'Pauline Betz'), ('all', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q229079'), ('winnerName', 'Polona Hercog'), ('all', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q259328'), ('winnerName', 'Rosemary Casals'), ('all', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q469884'), ('winnerName', 'Spencer Gore'), ('all', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q3042015'), ('winnerName', 'Stéphane Houdet'), ('all', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q3291835'), ('winnerName', 'Tiago Fernandes'), ('all', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q77157'), ('winnerName', 'Annika Beck'), ('all', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q5005599'), ('winnerName', 'Błażej Koniusz'), ('all', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q45405'), ('winnerName', 'Christina McHale'), ('all', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q1084238'), ('winnerName', 'Christo van Rensburg'), ('all', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q53371'), ('winnerName', 'Dorothy Cheney'), ('all', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q436000'), ('winnerName', 'Ellen Roosevelt'), ('all', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q258950'), ('winnerName', 'Evgeniya Rodina'), ('all', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q963755'), ('winnerName', 'Frank Parker'), ('all', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q204279'), ('winnerName', 'Goran Ivanišević'), ('all', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q62174'), ('winnerName', 'Hilde Krahwinkel Sperling'), ('all', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q232472'), ('winnerName', 'Iva Majoli'), ('all', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q5551564'), ('winnerName', 'Jeļena Ostapenko'), ('all', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q524807'), ('winnerName', 'JoAnne Russell'), ('all', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q234480'), ('winnerName', 'Květa Peschke'), ('all', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q17386379'), ('winnerName', 'Lucas Miedler'), ('all', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q1365348'), ('winnerName', 'Luke Jensen'), ('all', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q18918709'), ('winnerName', 'Markéta Vondroušová'), ('all', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q456740'), ('winnerName', 'Meredith McGrath'), ('all', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q3320069'), ('winnerName', 'Mona Guerrant'), ('all', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q709909'), ('winnerName', 'Nicola Pietrangeli'), ('all', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q926656'), ('winnerName', 'Paul Annacone'), ('all', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q299610'), ('winnerName', 'Peggy Michel'), ('all', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q229087'), ('winnerName', 'Peng Shuai'), ('all', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q455453'), ('winnerName', 'Rika Hiraki'), ('all', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q931939'), ('winnerName', 'Robert Wrenn'), ('all', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q66309318'), ('winnerName', 'Robin Montgomery'), ('all', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q1026173'), ('winnerName', 'Sharon Fichman'), ('all', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q766964'), ('winnerName', 'Taylor Townsend'), ('all', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q365139'), ('winnerName', 'William Renshaw'), ('all', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q702989'), ('winnerName', 'Yang Tsung-hua'), ('all', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q227389'), ('winnerName', 'Zsuzsa Körmöczy'), ('all', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q8080164'), ('winnerName', 'İpek Soylu'), ('all', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q20088944'), ('winnerName', 'Anna Kalinskaya'), ('all', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q370019'), ('winnerName', 'Balázs Taróczy'), ('all', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q293082'), ('winnerName', 'Betsy Nagelsen'), ('all', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q193361'), ('winnerName', 'Carlos Moyá'), ('all', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q53555'), ('winnerName', 'Carly Gullickson'), ('all', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q30767'), ('winnerName', 'Caroline Wozniacki'), ('all', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q232618'), ('winnerName', 'Conchita Martínez'), ('all', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q60238030'), ('winnerName', 'Dalibor Svrčina'), ('all', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q65553008'), ('winnerName', 'Daria Snigur'), ('all', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q3210313'), ('winnerName', 'Demi Schuurs'), ('all', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q88762'), ('winnerName', 'Dominic Thiem'), ('all', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q715784'), ('winnerName', 'Donald Johnson'), ('all', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q299959'), ('winnerName', 'Eileen Bennett Whittingstall'), ('all', '1')]
# [('winner', 'http://www.wikidata.org/entity/Q469922'), ('winnerName', 'Frank Hadow'), ('all', '1')]
# 100

# %%
# write your queries
# Consider the country for sport property of the tennis player (NO Country of citizenship). 
# Return the countries with at least one player who won at least one edition of each Grand Slam (the result set must be a list of country IRI and label).

# P31 ('instance of')
# P527 ('has part')
# P1346 ('winner')
# P1532 ('country for sport')

# GROUP BY ?winner & ?tournament
# ORDERING
# LIMIT extended to 100

# CREATING outer query -> prob result is incorrect, it should have atmost 4 as there are only 4 tournaments possible but 
#                         it is keeping only one row for each player from inner query
# TRYING to debug with one player specifically ('Natasha Zvereva')
# FILTER with wrong parametes, added regex
# FIND, I need to group also in the outer select

# Checking correctness, ORDER BY + HAVING


queryString = """

PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
SELECT ?winner ?winnerName (count(*) as ?all)
WHERE {
    {
        SELECT DISTINCT ?winner ?winnerName ?tournamentName (COUNT(*) AS ?tot)
        WHERE {
           # All four tourmamets in Grand Slam
           VALUES (?tournament){
               (wd:Q43605)  # French Open
               (wd:Q123577) # US Open
               (wd:Q41520)  # Wimbledon Championships
               (wd:Q60874)  # Australian Open
           }
           # ?yearlyTournament wdt:P31 ?tournament.
           # ?yearlyTournament wdt:P527 ?subTournament.
           # ?subTournament wdt:P1346 ?winner;
                           wdt:P2094 ?competitionClass.

           # ?winner wdt:P1532 ?countryForSport.

           # get the label 
           # ?tournament sc:name ?tournamentName .
           # ?yearlyTournament sc:name ?yearlyTournamentName .
           # ?subTournament sc:name ?subTournamentName.
           # ?winner sc:name ?winnerName.
           # ?competitionClass sc:name ?competitionClassName.
        }
        GROUP BY ?winner ?winnerName ?tournamentName
        ORDER BY ?winnerName ?tot
    }
    #FILTER (regex(?winnerName,"Natasha Zvereva"))
}
GROUP BY ?winner ?winnerName
HAVING (count(*) >=3)
ORDER BY asc (?all)
LIMIT 100

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('winner', 'http://www.wikidata.org/entity/Q255011'), ('winnerName', 'Hana Mandlíková'), ('all', '3')]
# [('winner', 'http://www.wikidata.org/entity/Q228989'), ('winnerName', 'Lucie Šafářová'), ('all', '3')]
# [('winner', 'http://www.wikidata.org/entity/Q16475'), ('winnerName', 'Mats Wilander'), ('all', '3')]
# [('winner', 'http://www.wikidata.org/entity/Q54537'), ('winnerName', 'Bethanie Mattek-Sands'), ('all', '3')]
# [('winner', 'http://www.wikidata.org/entity/Q317820'), ('winnerName', 'Jamie Murray'), ('all', '3')]
# [('winner', 'http://www.wikidata.org/entity/Q1289530'), ('winnerName', 'Marty Riessen'), ('all', '3')]
# [('winner', 'http://www.wikidata.org/entity/Q241727'), ('winnerName', 'Angela Mortimer'), ('all', '3')]
# [('winner', 'http://www.wikidata.org/entity/Q228559'), ('winnerName', 'Evonne Goolagong Cawley'), ('all', '3')]
# [('winner', 'http://www.wikidata.org/entity/Q60980388'), ('winnerName', 'Jonáš Forejtek'), ('all', '3')]
# [('winner', 'http://www.wikidata.org/entity/Q6277349'), ('winnerName', 'Jordanne Whiley'), ('all', '3')]
# [('winner', 'http://www.wikidata.org/entity/Q229005'), ('winnerName', 'Sara Errani'), ('all', '3')]
# [('winner', 'http://www.wikidata.org/entity/Q229093'), ('winnerName', 'Virginia Ruano Pascual'), ('all', '3')]
# [('winner', 'http://www.wikidata.org/entity/Q298542'), ('winnerName', 'Daniel Nestor'), ('all', '3')]
# [('winner', 'http://www.wikidata.org/entity/Q953688'), ('winnerName', 'Ekaterina Valeryevna Makarova'), ('all', '3')]
# [('winner', 'http://www.wikidata.org/entity/Q242959'), ('winnerName', 'Kristina Mladenovic'), ('all', '3')]
# [('winner', 'http://www.wikidata.org/entity/Q11666'), ('winnerName', 'Maria Sharapova'), ('all', '3')]
# [('winner', 'http://www.wikidata.org/entity/Q53390'), ('winnerName', 'Maureen Connolly'), ('all', '3')]
# [('winner', 'http://www.wikidata.org/entity/Q53424'), ('winnerName', 'Shirley Fry'), ('all', '3')]
# [('winner', 'http://www.wikidata.org/entity/Q239765'), ('winnerName', 'Tímea Babos'), ('all', '3')]
# [('winner', 'http://www.wikidata.org/entity/Q310380'), ('winnerName', 'Jonas Björkman'), ('all', '3')]
# [('winner', 'http://www.wikidata.org/entity/Q312554'), ('winnerName', 'Mahesh Bhupathi'), ('all', '3')]
# [('winner', 'http://www.wikidata.org/entity/Q173633'), ('winnerName', 'Monica Seles'), ('all', '3')]
# [('winner', 'http://www.wikidata.org/entity/Q233234'), ('winnerName', 'Virginia Wade'), ('all', '3')]
# [('winner', 'http://www.wikidata.org/entity/Q52430'), ('winnerName', 'Daniela Hantuchová'), ('all', '3')]
# [('winner', 'http://www.wikidata.org/entity/Q53564'), ('winnerName', 'Doris Hart'), ('all', '3')]
# [('winner', 'http://www.wikidata.org/entity/Q182736'), ('winnerName', 'Ivan Lendl'), ('all', '3')]
# [('winner', 'http://www.wikidata.org/entity/Q53393'), ('winnerName', 'Jimmy Connors'), ('all', '3')]
# [('winner', 'http://www.wikidata.org/entity/Q16474'), ('winnerName', 'John McEnroe'), ('all', '3')]
# [('winner', 'http://www.wikidata.org/entity/Q921488'), ('winnerName', 'Juan Sebastián Cabal'), ('all', '3')]
# [('winner', 'http://www.wikidata.org/entity/Q240695'), ('winnerName', 'Larisa Neiland'), ('all', '3')]
# [('winner', 'http://www.wikidata.org/entity/Q455136'), ('winnerName', 'Anders Järryd'), ('all', '3')]
# [('winner', 'http://www.wikidata.org/entity/Q84056'), ('winnerName', 'Ashleigh Barty'), ('all', '3')]
# [('winner', 'http://www.wikidata.org/entity/Q17381675'), ('winnerName', 'Elise Mertens'), ('all', '3')]
# [('winner', 'http://www.wikidata.org/entity/Q105550'), ('winnerName', 'Rod Laver'), ('all', '3')]
# [('winner', 'http://www.wikidata.org/entity/Q189542'), ('winnerName', 'Stefan Edberg'), ('all', '3')]
# [('winner', 'http://www.wikidata.org/entity/Q207705'), ('winnerName', 'Yevgeny Kafelnikov'), ('all', '3')]
# [('winner', 'http://www.wikidata.org/entity/Q53565'), ('winnerName', 'Liezel Huber'), ('all', '3')]
# [('winner', 'http://www.wikidata.org/entity/Q229116'), ('winnerName', 'Katarina Srebotnik'), ('all', '3')]
# [('winner', 'http://www.wikidata.org/entity/Q10129'), ('winnerName', 'Lisa Raymond'), ('all', '3')]
# [('winner', 'http://www.wikidata.org/entity/Q210695'), ('winnerName', 'Mary Pierce'), ('all', '3')]
# [('winner', 'http://www.wikidata.org/entity/Q193661'), ('winnerName', 'Stan Wawrinka'), ('all', '3')]
# [('winner', 'http://www.wikidata.org/entity/Q259282'), ('winnerName', 'Betty Stöve'), ('all', '3')]
# [('winner', 'http://www.wikidata.org/entity/Q234624'), ('winnerName', 'Latisha Chan'), ('all', '3')]
# [('winner', 'http://www.wikidata.org/entity/Q291677'), ('winnerName', 'Manon Bollegraf'), ('all', '3')]
# [('winner', 'http://www.wikidata.org/entity/Q317974'), ('winnerName', 'Nicolas Mahut'), ('all', '3')]
# [('winner', 'http://www.wikidata.org/entity/Q77178'), ('winnerName', 'Angelique Kerber'), ('all', '3')]
# [('winner', 'http://www.wikidata.org/entity/Q324515'), ('winnerName', 'Ivan Dodig'), ('all', '3')]
# [('winner', 'http://www.wikidata.org/entity/Q1588571'), ('winnerName', 'Mate Pavić'), ('all', '3')]
# [('winner', 'http://www.wikidata.org/entity/Q715130'), ('winnerName', 'Rick Leach'), ('all', '3')]
# [('winner', 'http://www.wikidata.org/entity/Q192064'), ('winnerName', 'Svetlana Kuznetsova'), ('all', '3')]
# [('winner', 'http://www.wikidata.org/entity/Q374053'), ('winnerName', 'Vera Zvonareva'), ('all', '3')]
# [('winner', 'http://www.wikidata.org/entity/Q188080'), ('winnerName', 'Arantxa Sánchez Vicario'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q264493'), ('winnerName', 'Kathy Jordan'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q233243'), ('winnerName', 'Natasha Zvereva'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q132147'), ('winnerName', 'Sania Mirza'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q233332'), ('winnerName', 'Gigi Fernández'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q233247'), ('winnerName', 'Maria Bueno'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q14286'), ('winnerName', 'Chris Evert'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q11685'), ('winnerName', 'Kim Clijsters'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q11578'), ('winnerName', 'Venus Williams'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q10132'), ('winnerName', 'Rafael Nadal'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q426049'), ('winnerName', 'John Fitzgerald'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q134720'), ('winnerName', 'Martina Hingis'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q5812'), ('winnerName', 'Novak Djokovic'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q11459'), ('winnerName', 'Serena Williams'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q16224602'), ('winnerName', 'Yui Kamiji'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q296282'), ('winnerName', 'Leander Paes'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q11677'), ('winnerName', 'Lindsay Davenport'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q54545'), ('winnerName', 'Martina Navratilova'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q2093033'), ('winnerName', 'Pierre-Hugues Herbert'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q634844'), ('winnerName', 'Elena Vesnina'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q11052500'), ('winnerName', 'Barbora Krejčíková'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q54527'), ('winnerName', 'Billie Jean King'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q229151'), ('winnerName', 'Helena Suková'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q229121'), ('winnerName', 'Jana Novotná'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q1426'), ('winnerName', 'Roger Federer'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q54654'), ('winnerName', 'Pam Shriver'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q11662'), ('winnerName', 'Steffi Graf'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q270414'), ('winnerName', 'Anne Smith'), ('all', '4')]
# 79

# %%
# write your queries
# Consider the country for sport property of the tennis player (NO Country of citizenship). 
# Return the countries with at least one player who won at least one edition of each Grand Slam (the result set must be a list of country IRI and label).

# P31 ('instance of')
# P527 ('has part')
# P1346 ('winner')
# P1532 ('country for sport')

# GROUP BY ?winner & ?tournament
# ORDERING
# LIMIT extended to 100

# CREATING outer query -> prob result is incorrect, it should have atmost 4 as there are only 4 tournaments possible but 
#                         it is keeping only one row for each player from inner query
# TRYING to debug with one player specifically ('Natasha Zvereva')
# FILTER with wrong parametes, added regex
# FIND, I need to group also in the outer select

# Checking correctness, ORDER BY + HAVING, OK
# Selecting players those who won all four tournaments in GS


queryString = """

PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
SELECT ?winner ?winnerName (count(*) as ?all)
WHERE {
    {
        SELECT DISTINCT ?winner ?winnerName ?tournamentName (COUNT(*) AS ?tot)
        WHERE {
           # All four tourmamets in Grand Slam
           VALUES (?tournament){
               (wd:Q43605)  # French Open
               (wd:Q123577) # US Open
               (wd:Q41520)  # Wimbledon Championships
               (wd:Q60874)  # Australian Open
           }
           # ?yearlyTournament wdt:P31 ?tournament.
           # ?yearlyTournament wdt:P527 ?subTournament.
           # ?subTournament wdt:P1346 ?winner;
                           wdt:P2094 ?competitionClass.

           # ?winner wdt:P1532 ?countryForSport.

           # get the label 
           # ?tournament sc:name ?tournamentName .
           # ?yearlyTournament sc:name ?yearlyTournamentName .
           # ?subTournament sc:name ?subTournamentName.
           # ?winner sc:name ?winnerName.
           # ?competitionClass sc:name ?competitionClassName.
        }
        GROUP BY ?winner ?winnerName ?tournamentName
        ORDER BY ?winnerName ?tot
    }
    #FILTER (regex(?winnerName,"Natasha Zvereva"))
}
GROUP BY ?winner ?winnerName
HAVING (count(*) >=4)
ORDER BY asc (?all)
LIMIT 100

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('winner', 'http://www.wikidata.org/entity/Q188080'), ('winnerName', 'Arantxa Sánchez Vicario'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q264493'), ('winnerName', 'Kathy Jordan'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q233243'), ('winnerName', 'Natasha Zvereva'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q132147'), ('winnerName', 'Sania Mirza'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q233332'), ('winnerName', 'Gigi Fernández'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q233247'), ('winnerName', 'Maria Bueno'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q14286'), ('winnerName', 'Chris Evert'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q11685'), ('winnerName', 'Kim Clijsters'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q11578'), ('winnerName', 'Venus Williams'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q10132'), ('winnerName', 'Rafael Nadal'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q426049'), ('winnerName', 'John Fitzgerald'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q134720'), ('winnerName', 'Martina Hingis'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q5812'), ('winnerName', 'Novak Djokovic'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q11459'), ('winnerName', 'Serena Williams'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q16224602'), ('winnerName', 'Yui Kamiji'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q296282'), ('winnerName', 'Leander Paes'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q11677'), ('winnerName', 'Lindsay Davenport'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q54545'), ('winnerName', 'Martina Navratilova'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q2093033'), ('winnerName', 'Pierre-Hugues Herbert'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q634844'), ('winnerName', 'Elena Vesnina'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q11052500'), ('winnerName', 'Barbora Krejčíková'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q54527'), ('winnerName', 'Billie Jean King'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q229151'), ('winnerName', 'Helena Suková'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q229121'), ('winnerName', 'Jana Novotná'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q1426'), ('winnerName', 'Roger Federer'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q54654'), ('winnerName', 'Pam Shriver'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q11662'), ('winnerName', 'Steffi Graf'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q270414'), ('winnerName', 'Anne Smith'), ('all', '4')]
# 28

# %%
# write your queries
# Consider the country for sport property of the tennis player (NO Country of citizenship). 
# Return the countries with at least one player who won at least one edition of each Grand Slam (the result set must be a list of country IRI and label).

# P31 ('instance of')
# P527 ('has part')
# P1346 ('winner')
# P1532 ('country for sport')

# GROUP BY ?winner & ?tournament
# ORDERING
# LIMIT extended to 100

# CREATING outer query -> prob result is incorrect, it should have atmost 4 as there are only 4 tournaments possible but 
#                         it is keeping only one row for each player from inner query
# TRYING to debug with one player specifically ('Natasha Zvereva')
# FILTER with wrong parametes, added regex
# FIND, I need to group also in the outer select

# Checking correctness, ORDER BY + HAVING, OK
# Selecting players those who won all four tournaments in GS

# removing ?winner wdt:P1532 ?countryForSport.


queryString = """

PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
SELECT ?winner ?winnerName (count(*) as ?all)
WHERE {
    {
        SELECT DISTINCT ?winner ?winnerName ?tournamentName (COUNT(*) AS ?tot)
        WHERE {
           # All four tourmamets in Grand Slam
           VALUES (?tournament){
               (wd:Q43605)  # French Open
               (wd:Q123577) # US Open
               (wd:Q41520)  # Wimbledon Championships
               (wd:Q60874)  # Australian Open
           }
           # ?yearlyTournament wdt:P31 ?tournament.
           # ?yearlyTournament wdt:P527 ?subTournament.
           # ?subTournament wdt:P1346 ?winner.

           # get the label 
           # ?tournament sc:name ?tournamentName .
           # ?winner sc:name ?winnerName.
        }
        GROUP BY ?winner ?winnerName ?tournamentName
        ORDER BY ?winnerName ?tot
    }
    #FILTER (regex(?winnerName,"Natasha Zvereva"))
}
GROUP BY ?winner ?winnerName
HAVING (count(*) >=4)
ORDER BY asc (?all)
LIMIT 100

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('winner', 'http://www.wikidata.org/entity/Q7407'), ('winnerName', 'Andre Agassi'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q188080'), ('winnerName', 'Arantxa Sánchez Vicario'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q52453'), ('winnerName', 'Bob Hewitt'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q264493'), ('winnerName', 'Kathy Jordan'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q233243'), ('winnerName', 'Natasha Zvereva'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q132147'), ('winnerName', 'Sania Mirza'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q233332'), ('winnerName', 'Gigi Fernández'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q233247'), ('winnerName', 'Maria Bueno'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q14286'), ('winnerName', 'Chris Evert'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q11685'), ('winnerName', 'Kim Clijsters'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q11578'), ('winnerName', 'Venus Williams'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q335333'), ('winnerName', 'Mark Knowles'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q10132'), ('winnerName', 'Rafael Nadal'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q426049'), ('winnerName', 'John Fitzgerald'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q360630'), ('winnerName', 'Mark Woodforde'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q134720'), ('winnerName', 'Martina Hingis'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q5812'), ('winnerName', 'Novak Djokovic'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q11459'), ('winnerName', 'Serena Williams'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q335312'), ('winnerName', 'Todd Woodbridge'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q16224602'), ('winnerName', 'Yui Kamiji'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q296282'), ('winnerName', 'Leander Paes'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q11677'), ('winnerName', 'Lindsay Davenport'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q54545'), ('winnerName', 'Martina Navratilova'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q2093033'), ('winnerName', 'Pierre-Hugues Herbert'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q229128'), ('winnerName', 'Cara Black'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q634844'), ('winnerName', 'Elena Vesnina'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q11052500'), ('winnerName', 'Barbora Krejčíková'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q54527'), ('winnerName', 'Billie Jean King'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q229151'), ('winnerName', 'Helena Suková'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q229121'), ('winnerName', 'Jana Novotná'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q1426'), ('winnerName', 'Roger Federer'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q24574661'), ('winnerName', 'Diede de Groot'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q53342'), ('winnerName', 'Mike Bryan'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q54654'), ('winnerName', 'Pam Shriver'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q11662'), ('winnerName', 'Steffi Graf'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q270414'), ('winnerName', 'Anne Smith'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q53340'), ('winnerName', 'Bob Bryan'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q560151'), ('winnerName', 'Jacco Eltingh'), ('all', '4')]
# 38

# %% [markdown]
# ##### 10 rows without country for sport ! DEBUGING STARTED:

# %%
# write your queries
# Consider the country for sport property of the tennis player (NO Country of citizenship). 
# Return the countries with at least one player who won at least one edition of each Grand Slam (the result set must be a list of country IRI and label).

# P31 ('instance of')
# P527 ('has part')
# P1346 ('winner')
# P1532 ('country for sport')

# GROUP BY ?winner & ?tournament
# ORDERING
# LIMIT extended to 100

# CREATING outer query -> prob result is incorrect, it should have atmost 4 as there are only 4 tournaments possible but 
#                         it is keeping only one row for each player from inner query
# TRYING to debug with one player specifically ('Natasha Zvereva')
# FILTER with wrong parametes, added regex
# FIND, I need to group also in the outer select

# Checking correctness, ORDER BY + HAVING, OK
# Selecting players those who won all four tournaments in GS

# DEBUGING


queryString = """

PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
SELECT ?winner ?winnerName (count(*) as ?all)
WHERE {
    {
        SELECT DISTINCT ?winner ?winnerName ?tournamentName (COUNT(*) AS ?tot)
        WHERE {
           # All four tourmamets in Grand Slam
           VALUES (?tournament){
               (wd:Q43605)  # French Open
               (wd:Q123577) # US Open
               (wd:Q41520)  # Wimbledon Championships
               (wd:Q60874)  # Australian Open
           }
           # ?yearlyTournament wdt:P31 ?tournament.
           # ?yearlyTournament wdt:P527 ?subTournament.
           # ?subTournament wdt:P1346 ?winner.

           # get the label 
           # ?tournament sc:name ?tournamentName .
           # ?winner sc:name ?winnerName.
        }
        GROUP BY ?winner ?winnerName ?tournamentName
        ORDER BY ?winnerName ?tot
    }
    #FILTER (regex(?winnerName,"Natasha Zvereva"))
}
GROUP BY ?winner ?winnerName
HAVING (count(*) >=4)
ORDER BY asc (?all)
LIMIT 100

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('winner', 'http://www.wikidata.org/entity/Q7407'), ('winnerName', 'Andre Agassi'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q188080'), ('winnerName', 'Arantxa Sánchez Vicario'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q52453'), ('winnerName', 'Bob Hewitt'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q264493'), ('winnerName', 'Kathy Jordan'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q233243'), ('winnerName', 'Natasha Zvereva'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q132147'), ('winnerName', 'Sania Mirza'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q233332'), ('winnerName', 'Gigi Fernández'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q233247'), ('winnerName', 'Maria Bueno'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q14286'), ('winnerName', 'Chris Evert'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q11685'), ('winnerName', 'Kim Clijsters'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q11578'), ('winnerName', 'Venus Williams'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q335333'), ('winnerName', 'Mark Knowles'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q10132'), ('winnerName', 'Rafael Nadal'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q426049'), ('winnerName', 'John Fitzgerald'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q360630'), ('winnerName', 'Mark Woodforde'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q134720'), ('winnerName', 'Martina Hingis'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q5812'), ('winnerName', 'Novak Djokovic'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q11459'), ('winnerName', 'Serena Williams'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q335312'), ('winnerName', 'Todd Woodbridge'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q16224602'), ('winnerName', 'Yui Kamiji'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q296282'), ('winnerName', 'Leander Paes'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q11677'), ('winnerName', 'Lindsay Davenport'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q54545'), ('winnerName', 'Martina Navratilova'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q2093033'), ('winnerName', 'Pierre-Hugues Herbert'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q229128'), ('winnerName', 'Cara Black'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q634844'), ('winnerName', 'Elena Vesnina'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q11052500'), ('winnerName', 'Barbora Krejčíková'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q54527'), ('winnerName', 'Billie Jean King'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q229151'), ('winnerName', 'Helena Suková'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q229121'), ('winnerName', 'Jana Novotná'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q1426'), ('winnerName', 'Roger Federer'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q24574661'), ('winnerName', 'Diede de Groot'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q53342'), ('winnerName', 'Mike Bryan'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q54654'), ('winnerName', 'Pam Shriver'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q11662'), ('winnerName', 'Steffi Graf'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q270414'), ('winnerName', 'Anne Smith'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q53340'), ('winnerName', 'Bob Bryan'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q560151'), ('winnerName', 'Jacco Eltingh'), ('all', '4')]
# 38

# %%
# write your queries
# Consider the country for sport property of the tennis player (NO Country of citizenship). 
# Return the countries with at least one player who won at least one edition of each Grand Slam (the result set must be a list of country IRI and label).

# P31 ('instance of')
# P527 ('has part')
# P1346 ('winner')
# P1532 ('country for sport')

# GROUP BY ?winner & ?tournament
# ORDERING
# LIMIT extended to 100

# CREATING outer query -> prob result is incorrect, it should have atmost 4 as there are only 4 tournaments possible but 
#                         it is keeping only one row for each player from inner query
# TRYING to debug with one player specifically ('Natasha Zvereva')
# FILTER with wrong parametes, added regex
# FIND, I need to group also in the outer select

# Checking correctness, ORDER BY + HAVING, OK
# Selecting players those who won all four tournaments in GS

# DEBUGING

queryString = """

PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
SELECT ?winner ?winnerName (count(*) as ?all)
WHERE {
    {
        SELECT DISTINCT ?winner ?winnerName ?tournamentName (COUNT(*) AS ?tot)
        WHERE {
           # All four tourmamets in Grand Slam
           VALUES (?tournament){
               (wd:Q43605)  # French Open
               (wd:Q123577) # US Open
               (wd:Q41520)  # Wimbledon Championships
               (wd:Q60874)  # Australian Open
           }
           # ?yearlyTournament wdt:P31 ?tournament.
           # ?yearlyTournament wdt:P527 ?subTournament.
           # ?subTournament wdt:P1346 ?winner.
           # ?winner wdt:P1532 ?countryForSport.

           # get the label 
           # ?tournament sc:name ?tournamentName .
           # ?winner sc:name ?winnerName.
        }
        GROUP BY ?winner ?winnerName ?tournamentName
        ORDER BY ?winnerName ?tot
    }
    #FILTER (regex(?winnerName,"Natasha Zvereva"))
}
GROUP BY ?winner ?winnerName
HAVING (count(*) >=4)
ORDER BY asc (?all)
LIMIT 100

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('winner', 'http://www.wikidata.org/entity/Q188080'), ('winnerName', 'Arantxa Sánchez Vicario'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q264493'), ('winnerName', 'Kathy Jordan'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q233243'), ('winnerName', 'Natasha Zvereva'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q132147'), ('winnerName', 'Sania Mirza'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q233332'), ('winnerName', 'Gigi Fernández'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q233247'), ('winnerName', 'Maria Bueno'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q14286'), ('winnerName', 'Chris Evert'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q11685'), ('winnerName', 'Kim Clijsters'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q11578'), ('winnerName', 'Venus Williams'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q10132'), ('winnerName', 'Rafael Nadal'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q426049'), ('winnerName', 'John Fitzgerald'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q134720'), ('winnerName', 'Martina Hingis'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q5812'), ('winnerName', 'Novak Djokovic'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q11459'), ('winnerName', 'Serena Williams'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q16224602'), ('winnerName', 'Yui Kamiji'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q296282'), ('winnerName', 'Leander Paes'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q11677'), ('winnerName', 'Lindsay Davenport'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q54545'), ('winnerName', 'Martina Navratilova'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q2093033'), ('winnerName', 'Pierre-Hugues Herbert'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q634844'), ('winnerName', 'Elena Vesnina'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q11052500'), ('winnerName', 'Barbora Krejčíková'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q54527'), ('winnerName', 'Billie Jean King'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q229151'), ('winnerName', 'Helena Suková'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q229121'), ('winnerName', 'Jana Novotná'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q1426'), ('winnerName', 'Roger Federer'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q54654'), ('winnerName', 'Pam Shriver'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q11662'), ('winnerName', 'Steffi Graf'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q270414'), ('winnerName', 'Anne Smith'), ('all', '4')]
# 28

# %%
# write your queries
# Consider the country for sport property of the tennis player (NO Country of citizenship). 
# Return the countries with at least one player who won at least one edition of each Grand Slam (the result set must be a list of country IRI and label).

# P31 ('instance of')
# P527 ('has part')
# P1346 ('winner')
# P1532 ('country for sport')

# GROUP BY ?winner & ?tournament
# ORDERING
# LIMIT extended to 100

# CREATING outer query -> prob result is incorrect, it should have atmost 4 as there are only 4 tournaments possible but 
#                         it is keeping only one row for each player from inner query
# TRYING to debug with one player specifically ('Natasha Zvereva')
# FILTER with wrong parametes, added regex
# FIND, I need to group also in the outer select

# Checking correctness, ORDER BY + HAVING, OK
# Selecting players those who won all four tournaments in GS

# DEBUGING


queryString = """

PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
SELECT ?winner ?winnerName (count(*) as ?all)
WHERE {
    {
        SELECT DISTINCT ?winner ?winnerName ?tournamentName (COUNT(*) AS ?tot)
        WHERE {
           # All four tourmamets in Grand Slam
           VALUES (?tournament){
               (wd:Q43605)  # French Open
               (wd:Q123577) # US Open
               (wd:Q41520)  # Wimbledon Championships
               (wd:Q60874)  # Australian Open
           }
           # ?yearlyTournament wdt:P31 ?tournament.
           # ?yearlyTournament wdt:P527 ?subTournament.
           # ?subTournament wdt:P1346 ?winner.

           # get the label 
           # ?tournament sc:name ?tournamentName .
           # ?winner sc:name ?winnerName.
        }
        GROUP BY ?winner ?winnerName ?tournamentName
        ORDER BY ?winnerName ?tot
    }
    #FILTER (regex(?winnerName,"Natasha Zvereva"))
}
GROUP BY ?winner ?winnerName
HAVING (count(*) >=4)
ORDER BY asc (?winnerName)
LIMIT 100

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('winner', 'http://www.wikidata.org/entity/Q7407'), ('winnerName', 'Andre Agassi'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q270414'), ('winnerName', 'Anne Smith'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q188080'), ('winnerName', 'Arantxa Sánchez Vicario'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q11052500'), ('winnerName', 'Barbora Krejčíková'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q54527'), ('winnerName', 'Billie Jean King'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q53340'), ('winnerName', 'Bob Bryan'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q52453'), ('winnerName', 'Bob Hewitt'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q229128'), ('winnerName', 'Cara Black'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q14286'), ('winnerName', 'Chris Evert'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q24574661'), ('winnerName', 'Diede de Groot'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q634844'), ('winnerName', 'Elena Vesnina'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q233332'), ('winnerName', 'Gigi Fernández'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q229151'), ('winnerName', 'Helena Suková'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q560151'), ('winnerName', 'Jacco Eltingh'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q229121'), ('winnerName', 'Jana Novotná'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q426049'), ('winnerName', 'John Fitzgerald'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q264493'), ('winnerName', 'Kathy Jordan'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q11685'), ('winnerName', 'Kim Clijsters'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q296282'), ('winnerName', 'Leander Paes'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q11677'), ('winnerName', 'Lindsay Davenport'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q233247'), ('winnerName', 'Maria Bueno'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q335333'), ('winnerName', 'Mark Knowles'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q360630'), ('winnerName', 'Mark Woodforde'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q134720'), ('winnerName', 'Martina Hingis'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q54545'), ('winnerName', 'Martina Navratilova'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q53342'), ('winnerName', 'Mike Bryan'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q233243'), ('winnerName', 'Natasha Zvereva'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q5812'), ('winnerName', 'Novak Djokovic'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q54654'), ('winnerName', 'Pam Shriver'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q2093033'), ('winnerName', 'Pierre-Hugues Herbert'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q10132'), ('winnerName', 'Rafael Nadal'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q1426'), ('winnerName', 'Roger Federer'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q132147'), ('winnerName', 'Sania Mirza'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q11459'), ('winnerName', 'Serena Williams'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q11662'), ('winnerName', 'Steffi Graf'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q335312'), ('winnerName', 'Todd Woodbridge'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q11578'), ('winnerName', 'Venus Williams'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q16224602'), ('winnerName', 'Yui Kamiji'), ('all', '4')]
# 38

# %%
# write your queries
# Consider the country for sport property of the tennis player (NO Country of citizenship). 
# Return the countries with at least one player who won at least one edition of each Grand Slam (the result set must be a list of country IRI and label).

# P31 ('instance of')
# P527 ('has part')
# P1346 ('winner')
# P1532 ('country for sport')

# GROUP BY ?winner & ?tournament
# ORDERING
# LIMIT extended to 100

# CREATING outer query -> prob result is incorrect, it should have atmost 4 as there are only 4 tournaments possible but 
#                         it is keeping only one row for each player from inner query
# TRYING to debug with one player specifically ('Natasha Zvereva')
# FILTER with wrong parametes, added regex
# FIND, I need to group also in the outer select

# Checking correctness, ORDER BY + HAVING, OK
# Selecting players those who won all four tournaments in GS

# DEBUGING


queryString = """

PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
SELECT ?winner ?winnerName (count(*) as ?all)
WHERE {
    {
        SELECT DISTINCT ?winner ?winnerName ?tournamentName (COUNT(*) AS ?tot)
        WHERE {
           # All four tourmamets in Grand Slam
           VALUES (?tournament){
               (wd:Q43605)  # French Open
               (wd:Q123577) # US Open
               (wd:Q41520)  # Wimbledon Championships
               (wd:Q60874)  # Australian Open
           }
           # ?yearlyTournament wdt:P31 ?tournament.
           # ?yearlyTournament wdt:P527 ?subTournament.
           # ?subTournament wdt:P1346 ?winner.
           # ?winner wdt:P1532 ?countryForSport.

           # get the label 
           # ?tournament sc:name ?tournamentName .
           # ?winner sc:name ?winnerName.
        }
        GROUP BY ?winner ?winnerName ?tournamentName
        ORDER BY ?winnerName ?tot
    }
    #FILTER (regex(?winnerName,"Natasha Zvereva"))
}
GROUP BY ?winner ?winnerName
HAVING (count(*) >=4)
ORDER BY asc (?winnerName)
LIMIT 100

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('winner', 'http://www.wikidata.org/entity/Q270414'), ('winnerName', 'Anne Smith'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q188080'), ('winnerName', 'Arantxa Sánchez Vicario'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q11052500'), ('winnerName', 'Barbora Krejčíková'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q54527'), ('winnerName', 'Billie Jean King'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q14286'), ('winnerName', 'Chris Evert'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q634844'), ('winnerName', 'Elena Vesnina'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q233332'), ('winnerName', 'Gigi Fernández'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q229151'), ('winnerName', 'Helena Suková'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q229121'), ('winnerName', 'Jana Novotná'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q426049'), ('winnerName', 'John Fitzgerald'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q264493'), ('winnerName', 'Kathy Jordan'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q11685'), ('winnerName', 'Kim Clijsters'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q296282'), ('winnerName', 'Leander Paes'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q11677'), ('winnerName', 'Lindsay Davenport'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q233247'), ('winnerName', 'Maria Bueno'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q134720'), ('winnerName', 'Martina Hingis'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q54545'), ('winnerName', 'Martina Navratilova'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q233243'), ('winnerName', 'Natasha Zvereva'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q5812'), ('winnerName', 'Novak Djokovic'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q54654'), ('winnerName', 'Pam Shriver'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q2093033'), ('winnerName', 'Pierre-Hugues Herbert'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q10132'), ('winnerName', 'Rafael Nadal'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q1426'), ('winnerName', 'Roger Federer'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q132147'), ('winnerName', 'Sania Mirza'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q11459'), ('winnerName', 'Serena Williams'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q11662'), ('winnerName', 'Steffi Graf'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q11578'), ('winnerName', 'Venus Williams'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q16224602'), ('winnerName', 'Yui Kamiji'), ('all', '4')]
# 28

# %%
# write your queries
# Consider the country for sport property of the tennis player (NO Country of citizenship). 
# Return the countries with at least one player who won at least one edition of each Grand Slam (the result set must be a list of country IRI and label).

# P31 ('instance of')
# P527 ('has part')
# P1346 ('winner')
# P1532 ('country for sport')

# GROUP BY ?winner & ?tournament
# ORDERING
# LIMIT extended to 100

# CREATING outer query -> prob result is incorrect, it should have atmost 4 as there are only 4 tournaments possible but 
#                         it is keeping only one row for each player from inner query
# TRYING to debug with one player specifically ('Natasha Zvereva')
# FILTER with wrong parametes, added regex
# FIND, I need to group also in the outer select

# Checking correctness, ORDER BY + HAVING, OK
# Selecting players those who won all four tournaments in GS

# DEBUGING


queryString = """

PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
SELECT ?winner ?winnerName (count(*) as ?all)
WHERE {
    {
        SELECT DISTINCT ?winner ?winnerName ?tournamentName (COUNT(*) AS ?tot)
        WHERE {
           # All four tourmamets in Grand Slam
           VALUES (?tournament){
               (wd:Q43605)  # French Open
               (wd:Q123577) # US Open
               (wd:Q41520)  # Wimbledon Championships
               (wd:Q60874)  # Australian Open
           }
           # ?yearlyTournament wdt:P31 ?tournament.
           # ?yearlyTournament wdt:P527 ?subTournament.
           # ?subTournament wdt:P1346 ?winner.

           # get the label 
           # ?tournament sc:name ?tournamentName .
           # ?winner sc:name ?winnerName.
        }
        GROUP BY ?winner ?winnerName ?tournamentName
        ORDER BY ?winnerName ?tot
    }
    #FILTER (regex(?winnerName,"Natasha Zvereva"))
}
GROUP BY ?winner ?winnerName
HAVING (count(*) >=4)
ORDER BY asc (?winnerName)
LIMIT 100

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('winner', 'http://www.wikidata.org/entity/Q7407'), ('winnerName', 'Andre Agassi'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q270414'), ('winnerName', 'Anne Smith'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q188080'), ('winnerName', 'Arantxa Sánchez Vicario'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q11052500'), ('winnerName', 'Barbora Krejčíková'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q54527'), ('winnerName', 'Billie Jean King'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q53340'), ('winnerName', 'Bob Bryan'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q52453'), ('winnerName', 'Bob Hewitt'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q229128'), ('winnerName', 'Cara Black'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q14286'), ('winnerName', 'Chris Evert'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q24574661'), ('winnerName', 'Diede de Groot'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q634844'), ('winnerName', 'Elena Vesnina'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q233332'), ('winnerName', 'Gigi Fernández'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q229151'), ('winnerName', 'Helena Suková'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q560151'), ('winnerName', 'Jacco Eltingh'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q229121'), ('winnerName', 'Jana Novotná'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q426049'), ('winnerName', 'John Fitzgerald'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q264493'), ('winnerName', 'Kathy Jordan'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q11685'), ('winnerName', 'Kim Clijsters'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q296282'), ('winnerName', 'Leander Paes'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q11677'), ('winnerName', 'Lindsay Davenport'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q233247'), ('winnerName', 'Maria Bueno'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q335333'), ('winnerName', 'Mark Knowles'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q360630'), ('winnerName', 'Mark Woodforde'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q134720'), ('winnerName', 'Martina Hingis'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q54545'), ('winnerName', 'Martina Navratilova'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q53342'), ('winnerName', 'Mike Bryan'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q233243'), ('winnerName', 'Natasha Zvereva'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q5812'), ('winnerName', 'Novak Djokovic'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q54654'), ('winnerName', 'Pam Shriver'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q2093033'), ('winnerName', 'Pierre-Hugues Herbert'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q10132'), ('winnerName', 'Rafael Nadal'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q1426'), ('winnerName', 'Roger Federer'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q132147'), ('winnerName', 'Sania Mirza'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q11459'), ('winnerName', 'Serena Williams'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q11662'), ('winnerName', 'Steffi Graf'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q335312'), ('winnerName', 'Todd Woodbridge'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q11578'), ('winnerName', 'Venus Williams'), ('all', '4')]
# [('winner', 'http://www.wikidata.org/entity/Q16224602'), ('winnerName', 'Yui Kamiji'), ('all', '4')]
# 38

# %%
# write your queries
# Consider the country for sport property of the tennis player (NO Country of citizenship). 
# Return the countries with at least one player who won at least one edition of each Grand Slam (the result set must be a list of country IRI and label).

# P31 ('instance of')
# P527 ('has part')
# P1346 ('winner')
# P1532 ('country for sport')

# GROUP BY ?winner & ?tournament
# ORDERING
# LIMIT extended to 100

# CREATING outer query -> prob result is incorrect, it should have atmost 4 as there are only 4 tournaments possible but 
#                         it is keeping only one row for each player from inner query
# TRYING to debug with one player specifically ('Natasha Zvereva')
# FILTER with wrong parametes, added regex
# FIND, I need to group also in the outer select

# Checking correctness, ORDER BY + HAVING, OK
# Selecting players those who won all four tournaments in GS

# DEBUGING


queryString = """

PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
        SELECT DISTINCT ?winner ?winnerName ?p ?pName
        WHERE {
           VALUES (?winner){
               (wd:Q7407)# 'winnerName', 'Andre Agassi'), ('all', '4')]
                (wd:Q270414)# 'winnerName', 'Anne Smith'), ('all', '4')]
                (wd:Q188080)# 'winnerName', 'Arantxa Sánchez Vicario'), ('all', '4')]
                (wd:Q11052500)# 'winnerName', 'Barbora Krejčíková'), ('all', '4')]
                (wd:Q54527)# 'winnerName', 'Billie Jean King'), ('all', '4')]
                (wd:Q53340)# 'winnerName', 'Bob Bryan'), ('all', '4')]
                (wd:Q52453)# 'winnerName', 'Bob Hewitt'), ('all', '4')]
                (wd:Q229128)# 'winnerName', 'Cara Black'), ('all', '4')]
                (wd:Q14286)# 'winnerName', 'Chris Evert'), ('all', '4')]
                (wd:Q24574661)# 'winnerName', 'Diede de Groot'), ('all', '4')]
                (wd:Q634844)# 'winnerName', 'Elena Vesnina'), ('all', '4')]
                (wd:Q233332)# 'winnerName', 'Gigi Fernández'), ('all', '4')]
                (wd:Q229151)# 'winnerName', 'Helena Suková'), ('all', '4')]
                (wd:Q560151)# 'winnerName', 'Jacco Eltingh'), ('all', '4')]
                (wd:Q229121)# 'winnerName', 'Jana Novotná'), ('all', '4')]
                (wd:Q426049)# 'winnerName', 'John Fitzgerald'), ('all', '4')]
                (wd:Q264493)# 'winnerName', 'Kathy Jordan'), ('all', '4')]
                (wd:Q11685)# 'winnerName', 'Kim Clijsters'), ('all', '4')]
                (wd:Q296282)# 'winnerName', 'Leander Paes'), ('all', '4')]
                (wd:Q11677)# 'winnerName', 'Lindsay Davenport'), ('all', '4')]
                (wd:Q233247)# 'winnerName', 'Maria Bueno'), ('all', '4')]
                (wd:Q335333)# 'winnerName', 'Mark Knowles'), ('all', '4')]
                (wd:Q360630)# 'winnerName', 'Mark Woodforde'), ('all', '4')]
                (wd:Q134720)# 'winnerName', 'Martina Hingis'), ('all', '4')]
                (wd:Q54545)# 'winnerName', 'Martina Navratilova'), ('all', '4')]
                (wd:Q53342)# 'winnerName', 'Mike Bryan'), ('all', '4')]
                (wd:Q233243)# 'winnerName', 'Natasha Zvereva'), ('all', '4')]
                (wd:Q5812)# 'winnerName', 'Novak Djokovic'), ('all', '4')]
                (wd:Q54654)# 'winnerName', 'Pam Shriver'), ('all', '4')]
                (wd:Q2093033)# 'winnerName', 'Pierre-Hugues Herbert'), ('all', '4')]
                (wd:Q10132)# 'winnerName', 'Rafael Nadal'), ('all', '4')]
                (wd:Q1426)# 'winnerName', 'Roger Federer'), ('all', '4')]
                (wd:Q132147)# 'winnerName', 'Sania Mirza'), ('all', '4')]
                (wd:Q11459)# 'winnerName', 'Serena Williams'), ('all', '4')]
                (wd:Q11662)# 'winnerName', 'Steffi Graf'), ('all', '4')]
                (wd:Q335312)# 'winnerName', 'Todd Woodbridge'), ('all', '4')]
                (wd:Q11578)# 'winnerName', 'Venus Williams'), ('all', '4')]
                (wd:Q16224602)# 'winnerName', 'Yui Kamiji'), ('all', '4')]
           }
           # ?winner ?p ?o.
           # get the label 
           # ?winner sc:name ?winnerName.
           # ?p sc:name ?pName.
           }
ORDER BY asc (?winnerName)
LIMIT 100

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('winner', 'http://www.wikidata.org/entity/Q7407'), ('winnerName', 'Andre Agassi'), ('p', 'http://www.wikidata.org/prop/direct/P3363'), ('pName', 'Tennis Hall of Fame player ID')]
# [('winner', 'http://www.wikidata.org/entity/Q7407'), ('winnerName', 'Andre Agassi'), ('p', 'http://www.wikidata.org/prop/direct/P1006'), ('pName', 'Nationale Thesaurus voor Auteurs ID')]
# [('winner', 'http://www.wikidata.org/entity/Q7407'), ('winnerName', 'Andre Agassi'), ('p', 'http://www.wikidata.org/prop/direct/P102'), ('pName', 'member of political party')]
# [('winner', 'http://www.wikidata.org/entity/Q7407'), ('winnerName', 'Andre Agassi'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('pName', 'occupation')]
# [('winner', 'http://www.wikidata.org/entity/Q7407'), ('winnerName', 'Andre Agassi'), ('p', 'http://www.wikidata.org/prop/direct/P1207'), ('pName', 'NUKAT ID')]
# [('winner', 'http://www.wikidata.org/entity/Q7407'), ('winnerName', 'Andre Agassi'), ('p', 'http://www.wikidata.org/prop/direct/P1263'), ('pName', 'NNDB people ID')]
# [('winner', 'http://www.wikidata.org/entity/Q7407'), ('winnerName', 'Andre Agassi'), ('p', 'http://www.wikidata.org/prop/direct/P1280'), ('pName', 'CONOR.SI ID')]
# [('winner', 'http://www.wikidata.org/entity/Q7407'), ('winnerName', 'Andre Agassi'), ('p', 'http://www.wikidata.org/prop/direct/P1285'), ('pName', 'Munzinger Sport number')]
# [('winner', 'http://www.wikidata.org/entity/Q7407'), ('winnerName', 'Andre Agassi'), ('p', 'http://www.wikidata.org/prop/direct/P1296'), ('pName', 'Gran Enciclopèdia Catalana ID')]
# [('winner', 'http://www.wikidata.org/entity/Q7407'), ('winnerName', 'Andre Agassi'), ('p', 'http://www.wikidata.org/prop/direct/P1315'), ('pName', 'NLA Trove ID')]
# [('winner', 'http://www.wikidata.org/entity/Q7407'), ('winnerName', 'Andre Agassi'), ('p', 'http://www.wikidata.org/prop/direct/P1343'), ('pName', 'described by source')]
# [('winner', 'http://www.wikidata.org/entity/Q7407'), ('winnerName', 'Andre Agassi'), ('p', 'http://www.wikidata.org/prop/direct/P1344'), ('pName', 'participant in')]
# [('winner', 'http://www.wikidata.org/entity/Q7407'), ('winnerName', 'Andre Agassi'), ('p', 'http://www.wikidata.org/prop/direct/P1412'), ('pName', 'languages spoken, written or signed')]
# [('winner', 'http://www.wikidata.org/entity/Q7407'), ('winnerName', 'Andre Agassi'), ('p', 'http://www.wikidata.org/prop/direct/P1417'), ('pName', 'Encyclopædia Britannica Online ID')]
# [('winner', 'http://www.wikidata.org/entity/Q7407'), ('winnerName', 'Andre Agassi'), ('p', 'http://www.wikidata.org/prop/direct/P1447'), ('pName', 'Sports-Reference.com Olympic athlete ID')]
# [('winner', 'http://www.wikidata.org/entity/Q7407'), ('winnerName', 'Andre Agassi'), ('p', 'http://www.wikidata.org/prop/direct/P1477'), ('pName', 'birth name')]
# [('winner', 'http://www.wikidata.org/entity/Q7407'), ('winnerName', 'Andre Agassi'), ('p', 'http://www.wikidata.org/prop/direct/P1559'), ('pName', 'name in native language')]
# [('winner', 'http://www.wikidata.org/entity/Q7407'), ('winnerName', 'Andre Agassi'), ('p', 'http://www.wikidata.org/prop/direct/P166'), ('pName', 'award received')]
# [('winner', 'http://www.wikidata.org/entity/Q7407'), ('winnerName', 'Andre Agassi'), ('p', 'http://www.wikidata.org/prop/direct/P1695'), ('pName', 'NLP ID (unique)')]
# [('winner', 'http://www.wikidata.org/entity/Q7407'), ('winnerName', 'Andre Agassi'), ('p', 'http://www.wikidata.org/prop/direct/P172'), ('pName', 'ethnic group')]
# [('winner', 'http://www.wikidata.org/entity/Q7407'), ('winnerName', 'Andre Agassi'), ('p', 'http://www.wikidata.org/prop/direct/P1741'), ('pName', 'GTAA ID')]
# [('winner', 'http://www.wikidata.org/entity/Q7407'), ('winnerName', 'Andre Agassi'), ('p', 'http://www.wikidata.org/prop/direct/P18'), ('pName', 'image')]
# [('winner', 'http://www.wikidata.org/entity/Q7407'), ('winnerName', 'Andre Agassi'), ('p', 'http://www.wikidata.org/prop/direct/P1819'), ('pName', 'genealogics.org person ID')]
# [('winner', 'http://www.wikidata.org/entity/Q7407'), ('winnerName', 'Andre Agassi'), ('p', 'http://www.wikidata.org/prop/direct/P19'), ('pName', 'place of birth')]
# [('winner', 'http://www.wikidata.org/entity/Q7407'), ('winnerName', 'Andre Agassi'), ('p', 'http://www.wikidata.org/prop/direct/P2002'), ('pName', 'Twitter username')]
# [('winner', 'http://www.wikidata.org/entity/Q7407'), ('winnerName', 'Andre Agassi'), ('p', 'http://www.wikidata.org/prop/direct/P2013'), ('pName', 'Facebook ID')]
# [('winner', 'http://www.wikidata.org/entity/Q7407'), ('winnerName', 'Andre Agassi'), ('p', 'http://www.wikidata.org/prop/direct/P2031'), ('pName', 'work period (start)')]
# [('winner', 'http://www.wikidata.org/entity/Q7407'), ('winnerName', 'Andre Agassi'), ('p', 'http://www.wikidata.org/prop/direct/P2032'), ('pName', 'work period (end)')]
# [('winner', 'http://www.wikidata.org/entity/Q7407'), ('winnerName', 'Andre Agassi'), ('p', 'http://www.wikidata.org/prop/direct/P2048'), ('pName', 'height')]
# [('winner', 'http://www.wikidata.org/entity/Q7407'), ('winnerName', 'Andre Agassi'), ('p', 'http://www.wikidata.org/prop/direct/P2067'), ('pName', 'mass')]
# [('winner', 'http://www.wikidata.org/entity/Q7407'), ('winnerName', 'Andre Agassi'), ('p', 'http://www.wikidata.org/prop/direct/P21'), ('pName', 'sex or gender')]
# [('winner', 'http://www.wikidata.org/entity/Q7407'), ('winnerName', 'Andre Agassi'), ('p', 'http://www.wikidata.org/prop/direct/P2121'), ('pName', 'prize money')]
# [('winner', 'http://www.wikidata.org/entity/Q7407'), ('winnerName', 'Andre Agassi'), ('p', 'http://www.wikidata.org/prop/direct/P213'), ('pName', 'ISNI')]
# [('winner', 'http://www.wikidata.org/entity/Q7407'), ('winnerName', 'Andre Agassi'), ('p', 'http://www.wikidata.org/prop/direct/P214'), ('pName', 'VIAF ID')]
# [('winner', 'http://www.wikidata.org/entity/Q7407'), ('winnerName', 'Andre Agassi'), ('p', 'http://www.wikidata.org/prop/direct/P2163'), ('pName', 'FAST ID')]
# [('winner', 'http://www.wikidata.org/entity/Q7407'), ('winnerName', 'Andre Agassi'), ('p', 'http://www.wikidata.org/prop/direct/P22'), ('pName', 'father')]
# [('winner', 'http://www.wikidata.org/entity/Q7407'), ('winnerName', 'Andre Agassi'), ('p', 'http://www.wikidata.org/prop/direct/P227'), ('pName', 'GND ID')]
# [('winner', 'http://www.wikidata.org/entity/Q7407'), ('winnerName', 'Andre Agassi'), ('p', 'http://www.wikidata.org/prop/direct/P244'), ('pName', 'Library of Congress authority ID')]
# [('winner', 'http://www.wikidata.org/entity/Q7407'), ('winnerName', 'Andre Agassi'), ('p', 'http://www.wikidata.org/prop/direct/P25'), ('pName', 'mother')]
# [('winner', 'http://www.wikidata.org/entity/Q7407'), ('winnerName', 'Andre Agassi'), ('p', 'http://www.wikidata.org/prop/direct/P26'), ('pName', 'spouse')]
# [('winner', 'http://www.wikidata.org/entity/Q7407'), ('winnerName', 'Andre Agassi'), ('p', 'http://www.wikidata.org/prop/direct/P2605'), ('pName', 'ČSFD person ID')]
# [('winner', 'http://www.wikidata.org/entity/Q7407'), ('winnerName', 'Andre Agassi'), ('p', 'http://www.wikidata.org/prop/direct/P268'), ('pName', 'Bibliothèque nationale de France ID')]
# [('winner', 'http://www.wikidata.org/entity/Q7407'), ('winnerName', 'Andre Agassi'), ('p', 'http://www.wikidata.org/prop/direct/P269'), ('pName', 'IdRef ID')]
# [('winner', 'http://www.wikidata.org/entity/Q7407'), ('winnerName', 'Andre Agassi'), ('p', 'http://www.wikidata.org/prop/direct/P27'), ('pName', 'country of citizenship')]
# [('winner', 'http://www.wikidata.org/entity/Q7407'), ('winnerName', 'Andre Agassi'), ('p', 'http://www.wikidata.org/prop/direct/P2734'), ('pName', 'Unz Review author ID')]
# [('winner', 'http://www.wikidata.org/entity/Q7407'), ('winnerName', 'Andre Agassi'), ('p', 'http://www.wikidata.org/prop/direct/P2924'), ('pName', 'Great Russian Encyclopedia Online ID')]
# [('winner', 'http://www.wikidata.org/entity/Q7407'), ('winnerName', 'Andre Agassi'), ('p', 'http://www.wikidata.org/prop/direct/P2949'), ('pName', 'WikiTree person ID')]
# [('winner', 'http://www.wikidata.org/entity/Q7407'), ('winnerName', 'Andre Agassi'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('winner', 'http://www.wikidata.org/entity/Q7407'), ('winnerName', 'Andre Agassi'), ('p', 'http://www.wikidata.org/prop/direct/P3171'), ('pName', 'Olympic.org athlete ID (archived version)')]
# [('winner', 'http://www.wikidata.org/entity/Q7407'), ('winnerName', 'Andre Agassi'), ('p', 'http://www.wikidata.org/prop/direct/P3219'), ('pName', 'Encyclopædia Universalis ID')]
# [('winner', 'http://www.wikidata.org/entity/Q7407'), ('winnerName', 'Andre Agassi'), ('p', 'http://www.wikidata.org/prop/direct/P3222'), ('pName', 'NE.se ID')]
# [('winner', 'http://www.wikidata.org/entity/Q7407'), ('winnerName', 'Andre Agassi'), ('p', 'http://www.wikidata.org/prop/direct/P3342'), ('pName', 'significant person')]
# [('winner', 'http://www.wikidata.org/entity/Q7407'), ('winnerName', 'Andre Agassi'), ('p', 'http://www.wikidata.org/prop/direct/P3365'), ('pName', 'Treccani ID')]
# [('winner', 'http://www.wikidata.org/entity/Q7407'), ('winnerName', 'Andre Agassi'), ('p', 'http://www.wikidata.org/prop/direct/P3368'), ('pName', 'Prabook ID')]
# [('winner', 'http://www.wikidata.org/entity/Q7407'), ('winnerName', 'Andre Agassi'), ('p', 'http://www.wikidata.org/prop/direct/P3417'), ('pName', 'Quora topic ID')]
# [('winner', 'http://www.wikidata.org/entity/Q7407'), ('winnerName', 'Andre Agassi'), ('p', 'http://www.wikidata.org/prop/direct/P3430'), ('pName', 'SNAC ARK ID')]
# [('winner', 'http://www.wikidata.org/entity/Q7407'), ('winnerName', 'Andre Agassi'), ('p', 'http://www.wikidata.org/prop/direct/P345'), ('pName', 'IMDb ID')]
# [('winner', 'http://www.wikidata.org/entity/Q7407'), ('winnerName', 'Andre Agassi'), ('p', 'http://www.wikidata.org/prop/direct/P349'), ('pName', 'National Diet Library ID')]
# [('winner', 'http://www.wikidata.org/entity/Q7407'), ('winnerName', 'Andre Agassi'), ('p', 'http://www.wikidata.org/prop/direct/P3630'), ('pName', 'Babelio author ID')]
# [('winner', 'http://www.wikidata.org/entity/Q7407'), ('winnerName', 'Andre Agassi'), ('p', 'http://www.wikidata.org/prop/direct/P373'), ('pName', 'Commons category')]
# [('winner', 'http://www.wikidata.org/entity/Q7407'), ('winnerName', 'Andre Agassi'), ('p', 'http://www.wikidata.org/prop/direct/P3987'), ('pName', 'SHARE Catalogue author ID')]
# [('winner', 'http://www.wikidata.org/entity/Q7407'), ('winnerName', 'Andre Agassi'), ('p', 'http://www.wikidata.org/prop/direct/P40'), ('pName', 'child')]
# [('winner', 'http://www.wikidata.org/entity/Q7407'), ('winnerName', 'Andre Agassi'), ('p', 'http://www.wikidata.org/prop/direct/P4342'), ('pName', 'Store norske leksikon ID')]
# [('winner', 'http://www.wikidata.org/entity/Q7407'), ('winnerName', 'Andre Agassi'), ('p', 'http://www.wikidata.org/prop/direct/P4544'), ('pName', 'Tennis Temple player ID')]
# [('winner', 'http://www.wikidata.org/entity/Q7407'), ('winnerName', 'Andre Agassi'), ('p', 'http://www.wikidata.org/prop/direct/P463'), ('pName', 'member of')]
# [('winner', 'http://www.wikidata.org/entity/Q7407'), ('winnerName', 'Andre Agassi'), ('p', 'http://www.wikidata.org/prop/direct/P4638'), ('pName', 'The Peerage person ID')]
# [('winner', 'http://www.wikidata.org/entity/Q7407'), ('winnerName', 'Andre Agassi'), ('p', 'http://www.wikidata.org/prop/direct/P4985'), ('pName', 'TMDb person ID')]
# [('winner', 'http://www.wikidata.org/entity/Q7407'), ('winnerName', 'Andre Agassi'), ('p', 'http://www.wikidata.org/prop/direct/P5019'), ('pName', 'Brockhaus Enzyklopädie online ID')]
# [('winner', 'http://www.wikidata.org/entity/Q7407'), ('winnerName', 'Andre Agassi'), ('p', 'http://www.wikidata.org/prop/direct/P5034'), ('pName', 'National Library of Korea ID')]
# [('winner', 'http://www.wikidata.org/entity/Q7407'), ('winnerName', 'Andre Agassi'), ('p', 'http://www.wikidata.org/prop/direct/P5247'), ('pName', 'Giant Bomb ID')]
# [('winner', 'http://www.wikidata.org/entity/Q7407'), ('winnerName', 'Andre Agassi'), ('p', 'http://www.wikidata.org/prop/direct/P54'), ('pName', 'member of sports team')]
# [('winner', 'http://www.wikidata.org/entity/Q7407'), ('winnerName', 'Andre Agassi'), ('p', 'http://www.wikidata.org/prop/direct/P5421'), ('pName', 'Trading Card Database person ID')]
# [('winner', 'http://www.wikidata.org/entity/Q7407'), ('winnerName', 'Andre Agassi'), ('p', 'http://www.wikidata.org/prop/direct/P551'), ('pName', 'residence')]
# [('winner', 'http://www.wikidata.org/entity/Q7407'), ('winnerName', 'Andre Agassi'), ('p', 'http://www.wikidata.org/prop/direct/P552'), ('pName', 'handedness')]
# [('winner', 'http://www.wikidata.org/entity/Q7407'), ('winnerName', 'Andre Agassi'), ('p', 'http://www.wikidata.org/prop/direct/P555'), ('pName', 'doubles record')]
# [('winner', 'http://www.wikidata.org/entity/Q7407'), ('winnerName', 'Andre Agassi'), ('p', 'http://www.wikidata.org/prop/direct/P5617'), ('pName', 'Evene ID')]
# [('winner', 'http://www.wikidata.org/entity/Q7407'), ('winnerName', 'Andre Agassi'), ('p', 'http://www.wikidata.org/prop/direct/P564'), ('pName', 'singles record')]
# [('winner', 'http://www.wikidata.org/entity/Q7407'), ('winnerName', 'Andre Agassi'), ('p', 'http://www.wikidata.org/prop/direct/P569'), ('pName', 'date of birth')]
# [('winner', 'http://www.wikidata.org/entity/Q7407'), ('winnerName', 'Andre Agassi'), ('p', 'http://www.wikidata.org/prop/direct/P5815'), ('pName', 'Olympics.com athlete ID')]
# [('winner', 'http://www.wikidata.org/entity/Q7407'), ('winnerName', 'Andre Agassi'), ('p', 'http://www.wikidata.org/prop/direct/P599'), ('pName', 'ITF player ID')]
# [('winner', 'http://www.wikidata.org/entity/Q7407'), ('winnerName', 'Andre Agassi'), ('p', 'http://www.wikidata.org/prop/direct/P641'), ('pName', 'sport')]
# [('winner', 'http://www.wikidata.org/entity/Q7407'), ('winnerName', 'Andre Agassi'), ('p', 'http://www.wikidata.org/prop/direct/P646'), ('pName', 'Freebase ID')]
# [('winner', 'http://www.wikidata.org/entity/Q7407'), ('winnerName', 'Andre Agassi'), ('p', 'http://www.wikidata.org/prop/direct/P648'), ('pName', 'Open Library ID')]
# [('winner', 'http://www.wikidata.org/entity/Q7407'), ('winnerName', 'Andre Agassi'), ('p', 'http://www.wikidata.org/prop/direct/P6706'), ('pName', 'De Agostini ID')]
# [('winner', 'http://www.wikidata.org/entity/Q7407'), ('winnerName', 'Andre Agassi'), ('p', 'http://www.wikidata.org/prop/direct/P6886'), ('pName', 'writing language')]
# [('winner', 'http://www.wikidata.org/entity/Q7407'), ('winnerName', 'Andre Agassi'), ('p', 'http://www.wikidata.org/prop/direct/P69'), ('pName', 'educated at')]
# [('winner', 'http://www.wikidata.org/entity/Q7407'), ('winnerName', 'Andre Agassi'), ('p', 'http://www.wikidata.org/prop/direct/P691'), ('pName', 'NKCR AUT ID')]
# [('winner', 'http://www.wikidata.org/entity/Q7407'), ('winnerName', 'Andre Agassi'), ('p', 'http://www.wikidata.org/prop/direct/P7293'), ('pName', 'PLWABN ID')]
# [('winner', 'http://www.wikidata.org/entity/Q7407'), ('winnerName', 'Andre Agassi'), ('p', 'http://www.wikidata.org/prop/direct/P734'), ('pName', 'family name')]
# [('winner', 'http://www.wikidata.org/entity/Q7407'), ('winnerName', 'Andre Agassi'), ('p', 'http://www.wikidata.org/prop/direct/P735'), ('pName', 'given name')]
# [('winner', 'http://www.wikidata.org/entity/Q7407'), ('winnerName', 'Andre Agassi'), ('p', 'http://www.wikidata.org/prop/direct/P741'), ('pName', 'playing hand')]
# [('winner', 'http://www.wikidata.org/entity/Q7407'), ('winnerName', 'Andre Agassi'), ('p', 'http://www.wikidata.org/prop/direct/P7666'), ('pName', 'Visuotinė lietuvių enciklopedija ID')]
# [('winner', 'http://www.wikidata.org/entity/Q7407'), ('winnerName', 'Andre Agassi'), ('p', 'http://www.wikidata.org/prop/direct/P7859'), ('pName', 'WorldCat Identities ID')]
# [('winner', 'http://www.wikidata.org/entity/Q7407'), ('winnerName', 'Andre Agassi'), ('p', 'http://www.wikidata.org/prop/direct/P7902'), ('pName', 'Deutsche Biographie (GND) ID')]
# [('winner', 'http://www.wikidata.org/entity/Q7407'), ('winnerName', 'Andre Agassi'), ('p', 'http://www.wikidata.org/prop/direct/P7929'), ('pName', 'Roglo person ID')]
# [('winner', 'http://www.wikidata.org/entity/Q7407'), ('winnerName', 'Andre Agassi'), ('p', 'http://www.wikidata.org/prop/direct/P8286'), ('pName', 'Olympedia people ID')]
# [('winner', 'http://www.wikidata.org/entity/Q7407'), ('winnerName', 'Andre Agassi'), ('p', 'http://www.wikidata.org/prop/direct/P8349'), ('pName', 'Proleksis enciklopedija ID')]
# [('winner', 'http://www.wikidata.org/entity/Q7407'), ('winnerName', 'Andre Agassi'), ('p', 'http://www.wikidata.org/prop/direct/P8618'), ('pName', 'ITF player ID 2020')]
# [('winner', 'http://www.wikidata.org/entity/Q7407'), ('winnerName', 'Andre Agassi'), ('p', 'http://www.wikidata.org/prop/direct/P866'), ('pName', 'Perlentaucher ID')]
# [('winner', 'http://www.wikidata.org/entity/Q7407'), ('winnerName', 'Andre Agassi'), ('p', 'http://www.wikidata.org/prop/direct/P8669'), ('pName', 'Encyclopaedia Beliana ID')]
# 100

# %%
# write your queries
# Consider the country for sport property of the tennis player (NO Country of citizenship). 
# Return the countries with at least one player who won at least one edition of each Grand Slam (the result set must be a list of country IRI and label).

# P31 ('instance of')
# P527 ('has part')
# P1346 ('winner')
# P1532 ('country for sport')

# GROUP BY ?winner & ?tournament
# ORDERING
# LIMIT extended to 100

# CREATING outer query -> prob result is incorrect, it should have atmost 4 as there are only 4 tournaments possible but 
#                         it is keeping only one row for each player from inner query
# TRYING to debug with one player specifically ('Natasha Zvereva')
# FILTER with wrong parametes, added regex
# FIND, I need to group also in the outer select

# Checking correctness, ORDER BY + HAVING, OK
# Selecting players those who won all four tournaments in GS

# DEBUGING


queryString = """

PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
        SELECT DISTINCT ?winner ?winnerName ?p ?pName
        WHERE {
           VALUES (?winner){
               (wd:Q7407)# 'winnerName', 'Andre Agassi'), ('all', '4')]
                (wd:Q270414)# 'winnerName', 'Anne Smith'), ('all', '4')]
                (wd:Q188080)# 'winnerName', 'Arantxa Sánchez Vicario'), ('all', '4')]
                (wd:Q11052500)# 'winnerName', 'Barbora Krejčíková'), ('all', '4')]
                (wd:Q54527)# 'winnerName', 'Billie Jean King'), ('all', '4')]
                (wd:Q53340)# 'winnerName', 'Bob Bryan'), ('all', '4')]
                (wd:Q52453)# 'winnerName', 'Bob Hewitt'), ('all', '4')]
                (wd:Q229128)# 'winnerName', 'Cara Black'), ('all', '4')]
                (wd:Q14286)# 'winnerName', 'Chris Evert'), ('all', '4')]
                (wd:Q24574661)# 'winnerName', 'Diede de Groot'), ('all', '4')]
                (wd:Q634844)# 'winnerName', 'Elena Vesnina'), ('all', '4')]
                (wd:Q233332)# 'winnerName', 'Gigi Fernández'), ('all', '4')]
                (wd:Q229151)# 'winnerName', 'Helena Suková'), ('all', '4')]
                (wd:Q560151)# 'winnerName', 'Jacco Eltingh'), ('all', '4')]
                (wd:Q229121)# 'winnerName', 'Jana Novotná'), ('all', '4')]
                (wd:Q426049)# 'winnerName', 'John Fitzgerald'), ('all', '4')]
                (wd:Q264493)# 'winnerName', 'Kathy Jordan'), ('all', '4')]
                (wd:Q11685)# 'winnerName', 'Kim Clijsters'), ('all', '4')]
                (wd:Q296282)# 'winnerName', 'Leander Paes'), ('all', '4')]
                (wd:Q11677)# 'winnerName', 'Lindsay Davenport'), ('all', '4')]
                (wd:Q233247)# 'winnerName', 'Maria Bueno'), ('all', '4')]
                (wd:Q335333)# 'winnerName', 'Mark Knowles'), ('all', '4')]
                (wd:Q360630)# 'winnerName', 'Mark Woodforde'), ('all', '4')]
                (wd:Q134720)# 'winnerName', 'Martina Hingis'), ('all', '4')]
                (wd:Q54545)# 'winnerName', 'Martina Navratilova'), ('all', '4')]
                (wd:Q53342)# 'winnerName', 'Mike Bryan'), ('all', '4')]
                (wd:Q233243)# 'winnerName', 'Natasha Zvereva'), ('all', '4')]
                (wd:Q5812)# 'winnerName', 'Novak Djokovic'), ('all', '4')]
                (wd:Q54654)# 'winnerName', 'Pam Shriver'), ('all', '4')]
                (wd:Q2093033)# 'winnerName', 'Pierre-Hugues Herbert'), ('all', '4')]
                (wd:Q10132)# 'winnerName', 'Rafael Nadal'), ('all', '4')]
                (wd:Q1426)# 'winnerName', 'Roger Federer'), ('all', '4')]
                (wd:Q132147)# 'winnerName', 'Sania Mirza'), ('all', '4')]
                (wd:Q11459)# 'winnerName', 'Serena Williams'), ('all', '4')]
                (wd:Q11662)# 'winnerName', 'Steffi Graf'), ('all', '4')]
                (wd:Q335312)# 'winnerName', 'Todd Woodbridge'), ('all', '4')]
                (wd:Q11578)# 'winnerName', 'Venus Williams'), ('all', '4')]
                (wd:Q16224602)# 'winnerName', 'Yui Kamiji'), ('all', '4')]
           }
           VALUES(?p){
           (wdt:P1532)
           }
           # ?winner ?p ?o.
           # get the label 
           # ?winner sc:name ?winnerName.
           # ?p sc:name ?pName.
           }
ORDER BY asc (?winnerName)
LIMIT 100

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('winner', 'http://www.wikidata.org/entity/Q270414'), ('winnerName', 'Anne Smith'), ('p', 'http://www.wikidata.org/prop/direct/P1532'), ('pName', 'country for sport')]
# [('winner', 'http://www.wikidata.org/entity/Q188080'), ('winnerName', 'Arantxa Sánchez Vicario'), ('p', 'http://www.wikidata.org/prop/direct/P1532'), ('pName', 'country for sport')]
# [('winner', 'http://www.wikidata.org/entity/Q11052500'), ('winnerName', 'Barbora Krejčíková'), ('p', 'http://www.wikidata.org/prop/direct/P1532'), ('pName', 'country for sport')]
# [('winner', 'http://www.wikidata.org/entity/Q54527'), ('winnerName', 'Billie Jean King'), ('p', 'http://www.wikidata.org/prop/direct/P1532'), ('pName', 'country for sport')]
# [('winner', 'http://www.wikidata.org/entity/Q14286'), ('winnerName', 'Chris Evert'), ('p', 'http://www.wikidata.org/prop/direct/P1532'), ('pName', 'country for sport')]
# [('winner', 'http://www.wikidata.org/entity/Q634844'), ('winnerName', 'Elena Vesnina'), ('p', 'http://www.wikidata.org/prop/direct/P1532'), ('pName', 'country for sport')]
# [('winner', 'http://www.wikidata.org/entity/Q233332'), ('winnerName', 'Gigi Fernández'), ('p', 'http://www.wikidata.org/prop/direct/P1532'), ('pName', 'country for sport')]
# [('winner', 'http://www.wikidata.org/entity/Q229151'), ('winnerName', 'Helena Suková'), ('p', 'http://www.wikidata.org/prop/direct/P1532'), ('pName', 'country for sport')]
# [('winner', 'http://www.wikidata.org/entity/Q229121'), ('winnerName', 'Jana Novotná'), ('p', 'http://www.wikidata.org/prop/direct/P1532'), ('pName', 'country for sport')]
# [('winner', 'http://www.wikidata.org/entity/Q426049'), ('winnerName', 'John Fitzgerald'), ('p', 'http://www.wikidata.org/prop/direct/P1532'), ('pName', 'country for sport')]
# [('winner', 'http://www.wikidata.org/entity/Q264493'), ('winnerName', 'Kathy Jordan'), ('p', 'http://www.wikidata.org/prop/direct/P1532'), ('pName', 'country for sport')]
# [('winner', 'http://www.wikidata.org/entity/Q11685'), ('winnerName', 'Kim Clijsters'), ('p', 'http://www.wikidata.org/prop/direct/P1532'), ('pName', 'country for sport')]
# [('winner', 'http://www.wikidata.org/entity/Q296282'), ('winnerName', 'Leander Paes'), ('p', 'http://www.wikidata.org/prop/direct/P1532'), ('pName', 'country for sport')]
# [('winner', 'http://www.wikidata.org/entity/Q11677'), ('winnerName', 'Lindsay Davenport'), ('p', 'http://www.wikidata.org/prop/direct/P1532'), ('pName', 'country for sport')]
# [('winner', 'http://www.wikidata.org/entity/Q233247'), ('winnerName', 'Maria Bueno'), ('p', 'http://www.wikidata.org/prop/direct/P1532'), ('pName', 'country for sport')]
# [('winner', 'http://www.wikidata.org/entity/Q134720'), ('winnerName', 'Martina Hingis'), ('p', 'http://www.wikidata.org/prop/direct/P1532'), ('pName', 'country for sport')]
# [('winner', 'http://www.wikidata.org/entity/Q54545'), ('winnerName', 'Martina Navratilova'), ('p', 'http://www.wikidata.org/prop/direct/P1532'), ('pName', 'country for sport')]
# [('winner', 'http://www.wikidata.org/entity/Q233243'), ('winnerName', 'Natasha Zvereva'), ('p', 'http://www.wikidata.org/prop/direct/P1532'), ('pName', 'country for sport')]
# [('winner', 'http://www.wikidata.org/entity/Q5812'), ('winnerName', 'Novak Djokovic'), ('p', 'http://www.wikidata.org/prop/direct/P1532'), ('pName', 'country for sport')]
# [('winner', 'http://www.wikidata.org/entity/Q54654'), ('winnerName', 'Pam Shriver'), ('p', 'http://www.wikidata.org/prop/direct/P1532'), ('pName', 'country for sport')]
# [('winner', 'http://www.wikidata.org/entity/Q2093033'), ('winnerName', 'Pierre-Hugues Herbert'), ('p', 'http://www.wikidata.org/prop/direct/P1532'), ('pName', 'country for sport')]
# [('winner', 'http://www.wikidata.org/entity/Q10132'), ('winnerName', 'Rafael Nadal'), ('p', 'http://www.wikidata.org/prop/direct/P1532'), ('pName', 'country for sport')]
# [('winner', 'http://www.wikidata.org/entity/Q1426'), ('winnerName', 'Roger Federer'), ('p', 'http://www.wikidata.org/prop/direct/P1532'), ('pName', 'country for sport')]
# [('winner', 'http://www.wikidata.org/entity/Q132147'), ('winnerName', 'Sania Mirza'), ('p', 'http://www.wikidata.org/prop/direct/P1532'), ('pName', 'country for sport')]
# [('winner', 'http://www.wikidata.org/entity/Q11459'), ('winnerName', 'Serena Williams'), ('p', 'http://www.wikidata.org/prop/direct/P1532'), ('pName', 'country for sport')]
# [('winner', 'http://www.wikidata.org/entity/Q11662'), ('winnerName', 'Steffi Graf'), ('p', 'http://www.wikidata.org/prop/direct/P1532'), ('pName', 'country for sport')]
# [('winner', 'http://www.wikidata.org/entity/Q11578'), ('winnerName', 'Venus Williams'), ('p', 'http://www.wikidata.org/prop/direct/P1532'), ('pName', 'country for sport')]
# [('winner', 'http://www.wikidata.org/entity/Q16224602'), ('winnerName', 'Yui Kamiji'), ('p', 'http://www.wikidata.org/prop/direct/P1532'), ('pName', 'country for sport')]
# 28

# %%
# write your queries
# Consider the country for sport property of the tennis player (NO Country of citizenship). 
# Return the countries with at least one player who won at least one edition of each Grand Slam (the result set must be a list of country IRI and label).

# P31 ('instance of')
# P527 ('has part')
# P1346 ('winner')
# P1532 ('country for sport')

# GROUP BY ?winner & ?tournament
# ORDERING
# LIMIT extended to 100

# CREATING outer query -> prob result is incorrect, it should have atmost 4 as there are only 4 tournaments possible but 
#                         it is keeping only one row for each player from inner query
# TRYING to debug with one player specifically ('Natasha Zvereva')
# FILTER with wrong parametes, added regex
# FIND, I need to group also in the outer select

# Checking correctness, ORDER BY + HAVING, OK
# Selecting players those who won all four tournaments in GS

# DEBUGING


queryString = """

PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
        SELECT DISTINCT ?winner ?winnerName ?p ?pName
        WHERE {
           VALUES (?winner){
               (wd:Q7407)# 'winnerName', 'Andre Agassi'), ('all', '4')]
                (wd:Q270414)# 'winnerName', 'Anne Smith'), ('all', '4')]
                (wd:Q188080)# 'winnerName', 'Arantxa Sánchez Vicario'), ('all', '4')]
                (wd:Q11052500)# 'winnerName', 'Barbora Krejčíková'), ('all', '4')]
                (wd:Q54527)# 'winnerName', 'Billie Jean King'), ('all', '4')]
                (wd:Q53340)# 'winnerName', 'Bob Bryan'), ('all', '4')]
                (wd:Q52453)# 'winnerName', 'Bob Hewitt'), ('all', '4')]
                (wd:Q229128)# 'winnerName', 'Cara Black'), ('all', '4')]
                (wd:Q14286)# 'winnerName', 'Chris Evert'), ('all', '4')]
                (wd:Q24574661)# 'winnerName', 'Diede de Groot'), ('all', '4')]
                (wd:Q634844)# 'winnerName', 'Elena Vesnina'), ('all', '4')]
                (wd:Q233332)# 'winnerName', 'Gigi Fernández'), ('all', '4')]
                (wd:Q229151)# 'winnerName', 'Helena Suková'), ('all', '4')]
                (wd:Q560151)# 'winnerName', 'Jacco Eltingh'), ('all', '4')]
                (wd:Q229121)# 'winnerName', 'Jana Novotná'), ('all', '4')]
                (wd:Q426049)# 'winnerName', 'John Fitzgerald'), ('all', '4')]
                (wd:Q264493)# 'winnerName', 'Kathy Jordan'), ('all', '4')]
                (wd:Q11685)# 'winnerName', 'Kim Clijsters'), ('all', '4')]
                (wd:Q296282)# 'winnerName', 'Leander Paes'), ('all', '4')]
                (wd:Q11677)# 'winnerName', 'Lindsay Davenport'), ('all', '4')]
                (wd:Q233247)# 'winnerName', 'Maria Bueno'), ('all', '4')]
                (wd:Q335333)# 'winnerName', 'Mark Knowles'), ('all', '4')]
                (wd:Q360630)# 'winnerName', 'Mark Woodforde'), ('all', '4')]
                (wd:Q134720)# 'winnerName', 'Martina Hingis'), ('all', '4')]
                (wd:Q54545)# 'winnerName', 'Martina Navratilova'), ('all', '4')]
                (wd:Q53342)# 'winnerName', 'Mike Bryan'), ('all', '4')]
                (wd:Q233243)# 'winnerName', 'Natasha Zvereva'), ('all', '4')]
                (wd:Q5812)# 'winnerName', 'Novak Djokovic'), ('all', '4')]
                (wd:Q54654)# 'winnerName', 'Pam Shriver'), ('all', '4')]
                (wd:Q2093033)# 'winnerName', 'Pierre-Hugues Herbert'), ('all', '4')]
                (wd:Q10132)# 'winnerName', 'Rafael Nadal'), ('all', '4')]
                (wd:Q1426)# 'winnerName', 'Roger Federer'), ('all', '4')]
                (wd:Q132147)# 'winnerName', 'Sania Mirza'), ('all', '4')]
                (wd:Q11459)# 'winnerName', 'Serena Williams'), ('all', '4')]
                (wd:Q11662)# 'winnerName', 'Steffi Graf'), ('all', '4')]
                (wd:Q335312)# 'winnerName', 'Todd Woodbridge'), ('all', '4')]
                (wd:Q11578)# 'winnerName', 'Venus Williams'), ('all', '4')]
                (wd:Q16224602)# 'winnerName', 'Yui Kamiji'), ('all', '4')]
           }
           #VALUES(?p){
           #(wdt:P1532)
           #}
           # ?winner ?p ?o.
           # get the label 
           # ?winner sc:name ?winnerName.
           # ?p sc:name ?pName.
           FILTER (regex(?pName, "country"))
           }
ORDER BY asc (?winnerName)
LIMIT 100

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('winner', 'http://www.wikidata.org/entity/Q7407'), ('winnerName', 'Andre Agassi'), ('p', 'http://www.wikidata.org/prop/direct/P27'), ('pName', 'country of citizenship')]
# [('winner', 'http://www.wikidata.org/entity/Q270414'), ('winnerName', 'Anne Smith'), ('p', 'http://www.wikidata.org/prop/direct/P1532'), ('pName', 'country for sport')]
# [('winner', 'http://www.wikidata.org/entity/Q270414'), ('winnerName', 'Anne Smith'), ('p', 'http://www.wikidata.org/prop/direct/P27'), ('pName', 'country of citizenship')]
# [('winner', 'http://www.wikidata.org/entity/Q188080'), ('winnerName', 'Arantxa Sánchez Vicario'), ('p', 'http://www.wikidata.org/prop/direct/P1532'), ('pName', 'country for sport')]
# [('winner', 'http://www.wikidata.org/entity/Q188080'), ('winnerName', 'Arantxa Sánchez Vicario'), ('p', 'http://www.wikidata.org/prop/direct/P27'), ('pName', 'country of citizenship')]
# [('winner', 'http://www.wikidata.org/entity/Q11052500'), ('winnerName', 'Barbora Krejčíková'), ('p', 'http://www.wikidata.org/prop/direct/P27'), ('pName', 'country of citizenship')]
# [('winner', 'http://www.wikidata.org/entity/Q11052500'), ('winnerName', 'Barbora Krejčíková'), ('p', 'http://www.wikidata.org/prop/direct/P1532'), ('pName', 'country for sport')]
# [('winner', 'http://www.wikidata.org/entity/Q54527'), ('winnerName', 'Billie Jean King'), ('p', 'http://www.wikidata.org/prop/direct/P1532'), ('pName', 'country for sport')]
# [('winner', 'http://www.wikidata.org/entity/Q54527'), ('winnerName', 'Billie Jean King'), ('p', 'http://www.wikidata.org/prop/direct/P27'), ('pName', 'country of citizenship')]
# [('winner', 'http://www.wikidata.org/entity/Q53340'), ('winnerName', 'Bob Bryan'), ('p', 'http://www.wikidata.org/prop/direct/P27'), ('pName', 'country of citizenship')]
# [('winner', 'http://www.wikidata.org/entity/Q52453'), ('winnerName', 'Bob Hewitt'), ('p', 'http://www.wikidata.org/prop/direct/P27'), ('pName', 'country of citizenship')]
# [('winner', 'http://www.wikidata.org/entity/Q229128'), ('winnerName', 'Cara Black'), ('p', 'http://www.wikidata.org/prop/direct/P27'), ('pName', 'country of citizenship')]
# [('winner', 'http://www.wikidata.org/entity/Q14286'), ('winnerName', 'Chris Evert'), ('p', 'http://www.wikidata.org/prop/direct/P1532'), ('pName', 'country for sport')]
# [('winner', 'http://www.wikidata.org/entity/Q14286'), ('winnerName', 'Chris Evert'), ('p', 'http://www.wikidata.org/prop/direct/P27'), ('pName', 'country of citizenship')]
# [('winner', 'http://www.wikidata.org/entity/Q24574661'), ('winnerName', 'Diede de Groot'), ('p', 'http://www.wikidata.org/prop/direct/P27'), ('pName', 'country of citizenship')]
# [('winner', 'http://www.wikidata.org/entity/Q634844'), ('winnerName', 'Elena Vesnina'), ('p', 'http://www.wikidata.org/prop/direct/P1532'), ('pName', 'country for sport')]
# [('winner', 'http://www.wikidata.org/entity/Q634844'), ('winnerName', 'Elena Vesnina'), ('p', 'http://www.wikidata.org/prop/direct/P27'), ('pName', 'country of citizenship')]
# [('winner', 'http://www.wikidata.org/entity/Q233332'), ('winnerName', 'Gigi Fernández'), ('p', 'http://www.wikidata.org/prop/direct/P1532'), ('pName', 'country for sport')]
# [('winner', 'http://www.wikidata.org/entity/Q233332'), ('winnerName', 'Gigi Fernández'), ('p', 'http://www.wikidata.org/prop/direct/P27'), ('pName', 'country of citizenship')]
# [('winner', 'http://www.wikidata.org/entity/Q229151'), ('winnerName', 'Helena Suková'), ('p', 'http://www.wikidata.org/prop/direct/P1532'), ('pName', 'country for sport')]
# [('winner', 'http://www.wikidata.org/entity/Q229151'), ('winnerName', 'Helena Suková'), ('p', 'http://www.wikidata.org/prop/direct/P27'), ('pName', 'country of citizenship')]
# [('winner', 'http://www.wikidata.org/entity/Q560151'), ('winnerName', 'Jacco Eltingh'), ('p', 'http://www.wikidata.org/prop/direct/P27'), ('pName', 'country of citizenship')]
# [('winner', 'http://www.wikidata.org/entity/Q229121'), ('winnerName', 'Jana Novotná'), ('p', 'http://www.wikidata.org/prop/direct/P1532'), ('pName', 'country for sport')]
# [('winner', 'http://www.wikidata.org/entity/Q229121'), ('winnerName', 'Jana Novotná'), ('p', 'http://www.wikidata.org/prop/direct/P27'), ('pName', 'country of citizenship')]
# [('winner', 'http://www.wikidata.org/entity/Q426049'), ('winnerName', 'John Fitzgerald'), ('p', 'http://www.wikidata.org/prop/direct/P1532'), ('pName', 'country for sport')]
# [('winner', 'http://www.wikidata.org/entity/Q426049'), ('winnerName', 'John Fitzgerald'), ('p', 'http://www.wikidata.org/prop/direct/P27'), ('pName', 'country of citizenship')]
# [('winner', 'http://www.wikidata.org/entity/Q264493'), ('winnerName', 'Kathy Jordan'), ('p', 'http://www.wikidata.org/prop/direct/P1532'), ('pName', 'country for sport')]
# [('winner', 'http://www.wikidata.org/entity/Q264493'), ('winnerName', 'Kathy Jordan'), ('p', 'http://www.wikidata.org/prop/direct/P27'), ('pName', 'country of citizenship')]
# [('winner', 'http://www.wikidata.org/entity/Q11685'), ('winnerName', 'Kim Clijsters'), ('p', 'http://www.wikidata.org/prop/direct/P1532'), ('pName', 'country for sport')]
# [('winner', 'http://www.wikidata.org/entity/Q11685'), ('winnerName', 'Kim Clijsters'), ('p', 'http://www.wikidata.org/prop/direct/P27'), ('pName', 'country of citizenship')]
# [('winner', 'http://www.wikidata.org/entity/Q296282'), ('winnerName', 'Leander Paes'), ('p', 'http://www.wikidata.org/prop/direct/P27'), ('pName', 'country of citizenship')]
# [('winner', 'http://www.wikidata.org/entity/Q296282'), ('winnerName', 'Leander Paes'), ('p', 'http://www.wikidata.org/prop/direct/P1532'), ('pName', 'country for sport')]
# [('winner', 'http://www.wikidata.org/entity/Q11677'), ('winnerName', 'Lindsay Davenport'), ('p', 'http://www.wikidata.org/prop/direct/P1532'), ('pName', 'country for sport')]
# [('winner', 'http://www.wikidata.org/entity/Q11677'), ('winnerName', 'Lindsay Davenport'), ('p', 'http://www.wikidata.org/prop/direct/P27'), ('pName', 'country of citizenship')]
# [('winner', 'http://www.wikidata.org/entity/Q233247'), ('winnerName', 'Maria Bueno'), ('p', 'http://www.wikidata.org/prop/direct/P27'), ('pName', 'country of citizenship')]
# [('winner', 'http://www.wikidata.org/entity/Q233247'), ('winnerName', 'Maria Bueno'), ('p', 'http://www.wikidata.org/prop/direct/P1532'), ('pName', 'country for sport')]
# [('winner', 'http://www.wikidata.org/entity/Q335333'), ('winnerName', 'Mark Knowles'), ('p', 'http://www.wikidata.org/prop/direct/P27'), ('pName', 'country of citizenship')]
# [('winner', 'http://www.wikidata.org/entity/Q360630'), ('winnerName', 'Mark Woodforde'), ('p', 'http://www.wikidata.org/prop/direct/P27'), ('pName', 'country of citizenship')]
# [('winner', 'http://www.wikidata.org/entity/Q134720'), ('winnerName', 'Martina Hingis'), ('p', 'http://www.wikidata.org/prop/direct/P1532'), ('pName', 'country for sport')]
# [('winner', 'http://www.wikidata.org/entity/Q134720'), ('winnerName', 'Martina Hingis'), ('p', 'http://www.wikidata.org/prop/direct/P27'), ('pName', 'country of citizenship')]
# [('winner', 'http://www.wikidata.org/entity/Q54545'), ('winnerName', 'Martina Navratilova'), ('p', 'http://www.wikidata.org/prop/direct/P27'), ('pName', 'country of citizenship')]
# [('winner', 'http://www.wikidata.org/entity/Q54545'), ('winnerName', 'Martina Navratilova'), ('p', 'http://www.wikidata.org/prop/direct/P1532'), ('pName', 'country for sport')]
# [('winner', 'http://www.wikidata.org/entity/Q53342'), ('winnerName', 'Mike Bryan'), ('p', 'http://www.wikidata.org/prop/direct/P27'), ('pName', 'country of citizenship')]
# [('winner', 'http://www.wikidata.org/entity/Q233243'), ('winnerName', 'Natasha Zvereva'), ('p', 'http://www.wikidata.org/prop/direct/P1532'), ('pName', 'country for sport')]
# [('winner', 'http://www.wikidata.org/entity/Q233243'), ('winnerName', 'Natasha Zvereva'), ('p', 'http://www.wikidata.org/prop/direct/P27'), ('pName', 'country of citizenship')]
# [('winner', 'http://www.wikidata.org/entity/Q5812'), ('winnerName', 'Novak Djokovic'), ('p', 'http://www.wikidata.org/prop/direct/P1532'), ('pName', 'country for sport')]
# [('winner', 'http://www.wikidata.org/entity/Q5812'), ('winnerName', 'Novak Djokovic'), ('p', 'http://www.wikidata.org/prop/direct/P27'), ('pName', 'country of citizenship')]
# [('winner', 'http://www.wikidata.org/entity/Q54654'), ('winnerName', 'Pam Shriver'), ('p', 'http://www.wikidata.org/prop/direct/P27'), ('pName', 'country of citizenship')]
# [('winner', 'http://www.wikidata.org/entity/Q54654'), ('winnerName', 'Pam Shriver'), ('p', 'http://www.wikidata.org/prop/direct/P1532'), ('pName', 'country for sport')]
# [('winner', 'http://www.wikidata.org/entity/Q2093033'), ('winnerName', 'Pierre-Hugues Herbert'), ('p', 'http://www.wikidata.org/prop/direct/P27'), ('pName', 'country of citizenship')]
# [('winner', 'http://www.wikidata.org/entity/Q2093033'), ('winnerName', 'Pierre-Hugues Herbert'), ('p', 'http://www.wikidata.org/prop/direct/P1532'), ('pName', 'country for sport')]
# [('winner', 'http://www.wikidata.org/entity/Q10132'), ('winnerName', 'Rafael Nadal'), ('p', 'http://www.wikidata.org/prop/direct/P1532'), ('pName', 'country for sport')]
# [('winner', 'http://www.wikidata.org/entity/Q10132'), ('winnerName', 'Rafael Nadal'), ('p', 'http://www.wikidata.org/prop/direct/P27'), ('pName', 'country of citizenship')]
# [('winner', 'http://www.wikidata.org/entity/Q1426'), ('winnerName', 'Roger Federer'), ('p', 'http://www.wikidata.org/prop/direct/P1532'), ('pName', 'country for sport')]
# [('winner', 'http://www.wikidata.org/entity/Q1426'), ('winnerName', 'Roger Federer'), ('p', 'http://www.wikidata.org/prop/direct/P27'), ('pName', 'country of citizenship')]
# [('winner', 'http://www.wikidata.org/entity/Q132147'), ('winnerName', 'Sania Mirza'), ('p', 'http://www.wikidata.org/prop/direct/P1532'), ('pName', 'country for sport')]
# [('winner', 'http://www.wikidata.org/entity/Q132147'), ('winnerName', 'Sania Mirza'), ('p', 'http://www.wikidata.org/prop/direct/P27'), ('pName', 'country of citizenship')]
# [('winner', 'http://www.wikidata.org/entity/Q11459'), ('winnerName', 'Serena Williams'), ('p', 'http://www.wikidata.org/prop/direct/P1532'), ('pName', 'country for sport')]
# [('winner', 'http://www.wikidata.org/entity/Q11459'), ('winnerName', 'Serena Williams'), ('p', 'http://www.wikidata.org/prop/direct/P27'), ('pName', 'country of citizenship')]
# [('winner', 'http://www.wikidata.org/entity/Q11662'), ('winnerName', 'Steffi Graf'), ('p', 'http://www.wikidata.org/prop/direct/P1532'), ('pName', 'country for sport')]
# [('winner', 'http://www.wikidata.org/entity/Q11662'), ('winnerName', 'Steffi Graf'), ('p', 'http://www.wikidata.org/prop/direct/P27'), ('pName', 'country of citizenship')]
# [('winner', 'http://www.wikidata.org/entity/Q335312'), ('winnerName', 'Todd Woodbridge'), ('p', 'http://www.wikidata.org/prop/direct/P27'), ('pName', 'country of citizenship')]
# [('winner', 'http://www.wikidata.org/entity/Q11578'), ('winnerName', 'Venus Williams'), ('p', 'http://www.wikidata.org/prop/direct/P1532'), ('pName', 'country for sport')]
# [('winner', 'http://www.wikidata.org/entity/Q11578'), ('winnerName', 'Venus Williams'), ('p', 'http://www.wikidata.org/prop/direct/P27'), ('pName', 'country of citizenship')]
# [('winner', 'http://www.wikidata.org/entity/Q16224602'), ('winnerName', 'Yui Kamiji'), ('p', 'http://www.wikidata.org/prop/direct/P27'), ('pName', 'country of citizenship')]
# [('winner', 'http://www.wikidata.org/entity/Q16224602'), ('winnerName', 'Yui Kamiji'), ('p', 'http://www.wikidata.org/prop/direct/P1532'), ('pName', 'country for sport')]
# 66

# %% [markdown]
# ##### End DEBUGGING: the 10 missing rows, they don't have P1532 (country for sport)

# %%
# write your queries
# Consider the country for sport property of the tennis player (NO Country of citizenship). 
# Return the countries with at least one player who won at least one edition of each Grand Slam (the result set must be a list of country IRI and label).

# P31 ('instance of')
# P527 ('has part')
# P1346 ('winner')
# P1532 ('country for sport')

# GROUP BY ?winner & ?tournament
# ORDERING
# LIMIT extended to 100
# CREATING outer query -> prob result is incorrect, it should have atmost 4 as there are only 4 tournaments possible but 
#                         it is keeping only one row for each player from inner query
# TRYING to debug with one player specifically ('Natasha Zvereva')
# FILTER with wrong parametes, added regex
# FIND, I need to group also in the outer select
# Checking correctness, ORDER BY + HAVING, OK
# Selecting players those who won all four tournaments in GS

# GETTING countryForSport for the winners



queryString = """

PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
SELECT ?player ?playerName ?winner ?winnerName ?countryForSport (count(*) as ?all)
WHERE {
    # ?player wdt:P1532 ?countryForSport;
            sc:name ?playerName.
    FILTER (?player = ?winner)
    {
        SELECT DISTINCT ?winner ?winnerName ?tournamentName (COUNT(*) AS ?tot)
        WHERE {
           # All four tourmamets in Grand Slam
           VALUES (?tournament){
               (wd:Q43605)  # French Open
               (wd:Q123577) # US Open
               (wd:Q41520)  # Wimbledon Championships
               (wd:Q60874)  # Australian Open
           }
           # ?yearlyTournament wdt:P31 ?tournament.
           # ?yearlyTournament wdt:P527 ?subTournament.
           # ?subTournament wdt:P1346 ?winner.

           # get the label 
           # ?tournament sc:name ?tournamentName .
           # ?winner sc:name ?winnerName.
        }
        GROUP BY ?winner ?winnerName ?tournamentName
        ORDER BY ?winnerName ?tot
    }
}
GROUP BY ?winner ?winnerName ?player ?playerName ?countryForSport
HAVING (count(*) >=4)
ORDER BY asc (?all)
LIMIT 100

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('player', 'http://www.wikidata.org/entity/Q17381675'), ('playerName', 'Sania Mirza'), ('winner', 'http://www.wikidata.org/entity/Q17381675'), ('winnerName', 'Sania Mirza'), ('countryForSport', 'http://www.wikidata.org/entity/Q668'), ('all', '4')]
# [('player', 'http://www.wikidata.org/entity/Q17381675'), ('playerName', 'Anne Smith'), ('winner', 'http://www.wikidata.org/entity/Q17381675'), ('winnerName', 'Anne Smith'), ('countryForSport', 'http://www.wikidata.org/entity/Q30'), ('all', '4')]
# [('player', 'http://www.wikidata.org/entity/Q95162'), ('playerName', 'Venus Williams'), ('winner', 'http://www.wikidata.org/entity/Q95162'), ('winnerName', 'Venus Williams'), ('countryForSport', 'http://www.wikidata.org/entity/Q30'), ('all', '4')]
# [('player', 'http://www.wikidata.org/entity/Q231962'), ('playerName', 'Yui Kamiji'), ('winner', 'http://www.wikidata.org/entity/Q231962'), ('winnerName', 'Yui Kamiji'), ('countryForSport', 'http://www.wikidata.org/entity/Q17'), ('all', '4')]
# [('player', 'http://www.wikidata.org/entity/Q333104'), ('playerName', 'Gigi Fernández'), ('winner', 'http://www.wikidata.org/entity/Q333104'), ('winnerName', 'Gigi Fernández'), ('countryForSport', 'http://www.wikidata.org/entity/Q30'), ('all', '4')]
# [('player', 'http://www.wikidata.org/entity/Q298542'), ('playerName', 'Roger Federer'), ('winner', 'http://www.wikidata.org/entity/Q298542'), ('winnerName', 'Roger Federer'), ('countryForSport', 'http://www.wikidata.org/entity/Q39'), ('all', '4')]
# [('player', 'http://www.wikidata.org/entity/Q10129'), ('playerName', 'Rafael Nadal'), ('winner', 'http://www.wikidata.org/entity/Q10129'), ('winnerName', 'Rafael Nadal'), ('countryForSport', 'http://www.wikidata.org/entity/Q29'), ('all', '4')]
# [('player', 'http://www.wikidata.org/entity/Q53369'), ('playerName', 'Pam Shriver'), ('winner', 'http://www.wikidata.org/entity/Q53369'), ('winnerName', 'Pam Shriver'), ('countryForSport', 'http://www.wikidata.org/entity/Q30'), ('all', '4')]
# [('player', 'http://www.wikidata.org/entity/Q233221'), ('playerName', 'Barbora Krejčíková'), ('winner', 'http://www.wikidata.org/entity/Q233221'), ('winnerName', 'Barbora Krejčíková'), ('countryForSport', 'http://www.wikidata.org/entity/Q213'), ('all', '4')]
# [('player', 'http://www.wikidata.org/entity/Q2446649'), ('playerName', 'Novak Djokovic'), ('winner', 'http://www.wikidata.org/entity/Q2446649'), ('winnerName', 'Novak Djokovic'), ('countryForSport', 'http://www.wikidata.org/entity/Q403'), ('all', '4')]
# [('player', 'http://www.wikidata.org/entity/Q26840238'), ('playerName', 'Chris Evert'), ('winner', 'http://www.wikidata.org/entity/Q26840238'), ('winnerName', 'Chris Evert'), ('countryForSport', 'http://www.wikidata.org/entity/Q30'), ('all', '4')]
# [('player', 'http://www.wikidata.org/entity/Q273594'), ('playerName', 'Leander Paes'), ('winner', 'http://www.wikidata.org/entity/Q273594'), ('winnerName', 'Leander Paes'), ('countryForSport', 'http://www.wikidata.org/entity/Q668'), ('all', '4')]
# [('player', 'http://www.wikidata.org/entity/Q455322'), ('playerName', 'Steffi Graf'), ('winner', 'http://www.wikidata.org/entity/Q455322'), ('winnerName', 'Steffi Graf'), ('countryForSport', 'http://www.wikidata.org/entity/Q183'), ('all', '4')]
# [('player', 'http://www.wikidata.org/entity/Q227389'), ('playerName', 'Martina Hingis'), ('winner', 'http://www.wikidata.org/entity/Q227389'), ('winnerName', 'Martina Hingis'), ('countryForSport', 'http://www.wikidata.org/entity/Q39'), ('all', '4')]
# [('player', 'http://www.wikidata.org/entity/Q552626'), ('playerName', 'Elena Vesnina'), ('winner', 'http://www.wikidata.org/entity/Q552626'), ('winnerName', 'Elena Vesnina'), ('countryForSport', 'http://www.wikidata.org/entity/Q159'), ('all', '4')]
# [('player', 'http://www.wikidata.org/entity/Q53564'), ('playerName', 'Natasha Zvereva'), ('winner', 'http://www.wikidata.org/entity/Q53564'), ('winnerName', 'Natasha Zvereva'), ('countryForSport', 'http://www.wikidata.org/entity/Q184'), ('all', '4')]
# [('player', 'http://www.wikidata.org/entity/Q219724'), ('playerName', 'Martina Navratilova'), ('winner', 'http://www.wikidata.org/entity/Q219724'), ('winnerName', 'Martina Navratilova'), ('countryForSport', 'http://www.wikidata.org/entity/Q213'), ('all', '4')]
# [('player', 'http://www.wikidata.org/entity/Q289388'), ('playerName', 'Billie Jean King'), ('winner', 'http://www.wikidata.org/entity/Q289388'), ('winnerName', 'Billie Jean King'), ('countryForSport', 'http://www.wikidata.org/entity/Q30'), ('all', '4')]
# [('player', 'http://www.wikidata.org/entity/Q440531'), ('playerName', 'Helena Suková'), ('winner', 'http://www.wikidata.org/entity/Q440531'), ('winnerName', 'Helena Suková'), ('countryForSport', 'http://www.wikidata.org/entity/Q213'), ('all', '4')]
# [('player', 'http://www.wikidata.org/entity/Q1588571'), ('playerName', 'Jana Novotná'), ('winner', 'http://www.wikidata.org/entity/Q1588571'), ('winnerName', 'Jana Novotná'), ('countryForSport', 'http://www.wikidata.org/entity/Q33946'), ('all', '4')]
# [('player', 'http://www.wikidata.org/entity/Q461253'), ('playerName', 'Maria Bueno'), ('winner', 'http://www.wikidata.org/entity/Q461253'), ('winnerName', 'Maria Bueno'), ('countryForSport', 'http://www.wikidata.org/entity/Q155'), ('all', '4')]
# [('player', 'http://www.wikidata.org/entity/Q210695'), ('playerName', 'Lindsay Davenport'), ('winner', 'http://www.wikidata.org/entity/Q210695'), ('winnerName', 'Lindsay Davenport'), ('countryForSport', 'http://www.wikidata.org/entity/Q30'), ('all', '4')]
# [('player', 'http://www.wikidata.org/entity/Q1348581'), ('playerName', 'Kathy Jordan'), ('winner', 'http://www.wikidata.org/entity/Q1348581'), ('winnerName', 'Kathy Jordan'), ('countryForSport', 'http://www.wikidata.org/entity/Q30'), ('all', '4')]
# [('player', 'http://www.wikidata.org/entity/Q11662'), ('playerName', 'Jana Novotná'), ('winner', 'http://www.wikidata.org/entity/Q11662'), ('winnerName', 'Jana Novotná'), ('countryForSport', 'http://www.wikidata.org/entity/Q213'), ('all', '4')]
# [('player', 'http://www.wikidata.org/entity/Q162487'), ('playerName', 'Martina Navratilova'), ('winner', 'http://www.wikidata.org/entity/Q162487'), ('winnerName', 'Martina Navratilova'), ('countryForSport', 'http://www.wikidata.org/entity/Q30'), ('all', '4')]
# [('player', 'http://www.wikidata.org/entity/Q134720'), ('playerName', 'Martina Navratilova'), ('winner', 'http://www.wikidata.org/entity/Q134720'), ('winnerName', 'Martina Navratilova'), ('countryForSport', 'http://www.wikidata.org/entity/Q33946'), ('all', '4')]
# [('player', 'http://www.wikidata.org/entity/Q233243'), ('playerName', 'Kim Clijsters'), ('winner', 'http://www.wikidata.org/entity/Q233243'), ('winnerName', 'Kim Clijsters'), ('countryForSport', 'http://www.wikidata.org/entity/Q31'), ('all', '4')]
# [('player', 'http://www.wikidata.org/entity/Q233231'), ('playerName', 'Serena Williams'), ('winner', 'http://www.wikidata.org/entity/Q233231'), ('winnerName', 'Serena Williams'), ('countryForSport', 'http://www.wikidata.org/entity/Q30'), ('all', '4')]
# [('player', 'http://www.wikidata.org/entity/Q173633'), ('playerName', 'Arantxa Sánchez Vicario'), ('winner', 'http://www.wikidata.org/entity/Q173633'), ('winnerName', 'Arantxa Sánchez Vicario'), ('countryForSport', 'http://www.wikidata.org/entity/Q29'), ('all', '4')]
# [('player', 'http://www.wikidata.org/entity/Q445602'), ('playerName', 'Pierre-Hugues Herbert'), ('winner', 'http://www.wikidata.org/entity/Q445602'), ('winnerName', 'Pierre-Hugues Herbert'), ('countryForSport', 'http://www.wikidata.org/entity/Q142'), ('all', '4')]
# [('player', 'http://www.wikidata.org/entity/Q2834043'), ('playerName', 'John Fitzgerald'), ('winner', 'http://www.wikidata.org/entity/Q2834043'), ('winnerName', 'John Fitzgerald'), ('countryForSport', 'http://www.wikidata.org/entity/Q408'), ('all', '4')]
# 31

# %%
# write your queries
# Consider the country for sport property of the tennis player (NO Country of citizenship). 
# Return the countries with at least one player who won at least one edition of each Grand Slam (the result set must be a list of country IRI and label).

# P31 ('instance of')
# P527 ('has part')
# P1346 ('winner')
# P1532 ('country for sport')

# GROUP BY ?winner & ?tournament
# ORDERING
# LIMIT extended to 100
# CREATING outer query -> prob result is incorrect, it should have atmost 4 as there are only 4 tournaments possible but 
#                         it is keeping only one row for each player from inner query
# TRYING to debug with one player specifically ('Natasha Zvereva')
# FILTER with wrong parametes, added regex
# FIND, I need to group also in the outer select
# Checking correctness, ORDER BY + HAVING, OK
# Selecting players those who won all four tournaments in GS

# GETTING countryForSport for the winners, Trying to change GROUP BY have more than 28 results


queryString = """

PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
SELECT ?player ?playerName ?countryForSport ?countryForSportName (count(*) as ?all)
WHERE {
    # ?player wdt:P1532 ?countryForSport;
            sc:name ?playerName.
    # ?countryForSport sc:name ?countryForSportName.
    FILTER (?player = ?winner)
    {
        SELECT DISTINCT ?winner ?winnerName ?tournamentName (COUNT(*) AS ?tot)
        WHERE {
           # All four tourmamets in Grand Slam
           VALUES (?tournament){
               (wd:Q43605)  # French Open
               (wd:Q123577) # US Open
               (wd:Q41520)  # Wimbledon Championships
               (wd:Q60874)  # Australian Open
           }
           # ?yearlyTournament wdt:P31 ?tournament.
           # ?yearlyTournament wdt:P527 ?subTournament.
           # ?subTournament wdt:P1346 ?winner.

           # get the label 
           # ?tournament sc:name ?tournamentName .
           # ?winner sc:name ?winnerName.
        }
        GROUP BY ?winner ?winnerName ?tournamentName
        ORDER BY ?winnerName ?tot
    }
}
GROUP BY ?player ?playerName ?countryForSport ?countryForSportName
HAVING (count(*) >=4)
ORDER BY asc (?all)
LIMIT 100

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('player', 'http://www.wikidata.org/entity/Q134720'), ('playerName', 'Martina Hingis'), ('countryForSport', 'http://www.wikidata.org/entity/Q39'), ('countryForSportName', 'Switzerland'), ('all', '4')]
# [('player', 'http://www.wikidata.org/entity/Q296282'), ('playerName', 'Leander Paes'), ('countryForSport', 'http://www.wikidata.org/entity/Q668'), ('countryForSportName', 'India'), ('all', '4')]
# [('player', 'http://www.wikidata.org/entity/Q5812'), ('playerName', 'Novak Djokovic'), ('countryForSport', 'http://www.wikidata.org/entity/Q403'), ('countryForSportName', 'Serbia'), ('all', '4')]
# [('player', 'http://www.wikidata.org/entity/Q132147'), ('playerName', 'Sania Mirza'), ('countryForSport', 'http://www.wikidata.org/entity/Q668'), ('countryForSportName', 'India'), ('all', '4')]
# [('player', 'http://www.wikidata.org/entity/Q634844'), ('playerName', 'Elena Vesnina'), ('countryForSport', 'http://www.wikidata.org/entity/Q159'), ('countryForSportName', 'Russia'), ('all', '4')]
# [('player', 'http://www.wikidata.org/entity/Q233332'), ('playerName', 'Gigi Fernández'), ('countryForSport', 'http://www.wikidata.org/entity/Q30'), ('countryForSportName', 'United States of America'), ('all', '4')]
# [('player', 'http://www.wikidata.org/entity/Q11677'), ('playerName', 'Lindsay Davenport'), ('countryForSport', 'http://www.wikidata.org/entity/Q30'), ('countryForSportName', 'United States of America'), ('all', '4')]
# [('player', 'http://www.wikidata.org/entity/Q11662'), ('playerName', 'Steffi Graf'), ('countryForSport', 'http://www.wikidata.org/entity/Q183'), ('countryForSportName', 'Germany'), ('all', '4')]
# [('player', 'http://www.wikidata.org/entity/Q270414'), ('playerName', 'Anne Smith'), ('countryForSport', 'http://www.wikidata.org/entity/Q30'), ('countryForSportName', 'United States of America'), ('all', '4')]
# [('player', 'http://www.wikidata.org/entity/Q54654'), ('playerName', 'Pam Shriver'), ('countryForSport', 'http://www.wikidata.org/entity/Q30'), ('countryForSportName', 'United States of America'), ('all', '4')]
# [('player', 'http://www.wikidata.org/entity/Q233247'), ('playerName', 'Maria Bueno'), ('countryForSport', 'http://www.wikidata.org/entity/Q155'), ('countryForSportName', 'Brazil'), ('all', '4')]
# [('player', 'http://www.wikidata.org/entity/Q11685'), ('playerName', 'Kim Clijsters'), ('countryForSport', 'http://www.wikidata.org/entity/Q31'), ('countryForSportName', 'Belgium'), ('all', '4')]
# [('player', 'http://www.wikidata.org/entity/Q2093033'), ('playerName', 'Pierre-Hugues Herbert'), ('countryForSport', 'http://www.wikidata.org/entity/Q142'), ('countryForSportName', 'France'), ('all', '4')]
# [('player', 'http://www.wikidata.org/entity/Q54545'), ('playerName', 'Martina Navratilova'), ('countryForSport', 'http://www.wikidata.org/entity/Q213'), ('countryForSportName', 'Czech Republic'), ('all', '4')]
# [('player', 'http://www.wikidata.org/entity/Q11052500'), ('playerName', 'Barbora Krejčíková'), ('countryForSport', 'http://www.wikidata.org/entity/Q213'), ('countryForSportName', 'Czech Republic'), ('all', '4')]
# [('player', 'http://www.wikidata.org/entity/Q11459'), ('playerName', 'Serena Williams'), ('countryForSport', 'http://www.wikidata.org/entity/Q30'), ('countryForSportName', 'United States of America'), ('all', '4')]
# [('player', 'http://www.wikidata.org/entity/Q229121'), ('playerName', 'Jana Novotná'), ('countryForSport', 'http://www.wikidata.org/entity/Q213'), ('countryForSportName', 'Czech Republic'), ('all', '4')]
# [('player', 'http://www.wikidata.org/entity/Q11578'), ('playerName', 'Venus Williams'), ('countryForSport', 'http://www.wikidata.org/entity/Q30'), ('countryForSportName', 'United States of America'), ('all', '4')]
# [('player', 'http://www.wikidata.org/entity/Q54545'), ('playerName', 'Martina Navratilova'), ('countryForSport', 'http://www.wikidata.org/entity/Q30'), ('countryForSportName', 'United States of America'), ('all', '4')]
# [('player', 'http://www.wikidata.org/entity/Q188080'), ('playerName', 'Arantxa Sánchez Vicario'), ('countryForSport', 'http://www.wikidata.org/entity/Q29'), ('countryForSportName', 'Spain'), ('all', '4')]
# [('player', 'http://www.wikidata.org/entity/Q233243'), ('playerName', 'Natasha Zvereva'), ('countryForSport', 'http://www.wikidata.org/entity/Q184'), ('countryForSportName', 'Belarus'), ('all', '4')]
# [('player', 'http://www.wikidata.org/entity/Q229151'), ('playerName', 'Helena Suková'), ('countryForSport', 'http://www.wikidata.org/entity/Q213'), ('countryForSportName', 'Czech Republic'), ('all', '4')]
# [('player', 'http://www.wikidata.org/entity/Q10132'), ('playerName', 'Rafael Nadal'), ('countryForSport', 'http://www.wikidata.org/entity/Q29'), ('countryForSportName', 'Spain'), ('all', '4')]
# [('player', 'http://www.wikidata.org/entity/Q229121'), ('playerName', 'Jana Novotná'), ('countryForSport', 'http://www.wikidata.org/entity/Q33946'), ('countryForSportName', 'Czechoslovakia'), ('all', '4')]
# [('player', 'http://www.wikidata.org/entity/Q1426'), ('playerName', 'Roger Federer'), ('countryForSport', 'http://www.wikidata.org/entity/Q39'), ('countryForSportName', 'Switzerland'), ('all', '4')]
# [('player', 'http://www.wikidata.org/entity/Q54545'), ('playerName', 'Martina Navratilova'), ('countryForSport', 'http://www.wikidata.org/entity/Q33946'), ('countryForSportName', 'Czechoslovakia'), ('all', '4')]
# [('player', 'http://www.wikidata.org/entity/Q426049'), ('playerName', 'John Fitzgerald'), ('countryForSport', 'http://www.wikidata.org/entity/Q408'), ('countryForSportName', 'Australia'), ('all', '4')]
# [('player', 'http://www.wikidata.org/entity/Q264493'), ('playerName', 'Kathy Jordan'), ('countryForSport', 'http://www.wikidata.org/entity/Q30'), ('countryForSportName', 'United States of America'), ('all', '4')]
# [('player', 'http://www.wikidata.org/entity/Q14286'), ('playerName', 'Chris Evert'), ('countryForSport', 'http://www.wikidata.org/entity/Q30'), ('countryForSportName', 'United States of America'), ('all', '4')]
# [('player', 'http://www.wikidata.org/entity/Q54527'), ('playerName', 'Billie Jean King'), ('countryForSport', 'http://www.wikidata.org/entity/Q30'), ('countryForSportName', 'United States of America'), ('all', '4')]
# [('player', 'http://www.wikidata.org/entity/Q16224602'), ('playerName', 'Yui Kamiji'), ('countryForSport', 'http://www.wikidata.org/entity/Q17'), ('countryForSportName', 'Japan'), ('all', '4')]
# 31

# %%
# write your queries
# Consider the country for sport property of the tennis player (NO Country of citizenship). 
# Return the countries with at least one player who won at least one edition of each Grand Slam (the result set must be a list of country IRI and label).

# P31 ('instance of')
# P527 ('has part')
# P1346 ('winner')
# P1532 ('country for sport')

# GROUP BY ?winner & ?tournament
# ORDERING
# LIMIT extended to 100
# CREATING outer query -> prob result is incorrect, it should have atmost 4 as there are only 4 tournaments possible but 
#                         it is keeping only one row for each player from inner query
# TRYING to debug with one player specifically ('Natasha Zvereva')
# FILTER with wrong parametes, added regex
# FIND, I need to group also in the outer select
# Checking correctness, ORDER BY + HAVING, OK
# Selecting players those who won all four tournaments in GS

# GETTING countryForSport for the winners, some players has more than one countryForSport
# GETTING END result


queryString = """

PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
SELECT DISTINCT ?countryForSport ?countryForSportName (count(*) as ?all)
WHERE {
    # ?player wdt:P1532 ?countryForSport;
            sc:name ?playerName.
    # ?countryForSport sc:name ?countryForSportName.
    FILTER (?player = ?winner)
    {
        SELECT DISTINCT ?winner ?winnerName ?tournamentName (COUNT(*) AS ?tot)
        WHERE {
           # All four tourmamets in Grand Slam
           VALUES (?tournament){
               (wd:Q43605)  # French Open
               (wd:Q123577) # US Open
               (wd:Q41520)  # Wimbledon Championships
               (wd:Q60874)  # Australian Open
           }
           # ?yearlyTournament wdt:P31 ?tournament.
           # ?yearlyTournament wdt:P527 ?subTournament.
           # ?subTournament wdt:P1346 ?winner.

           # get the label 
           # ?tournament sc:name ?tournamentName .
           # ?winner sc:name ?winnerName.
        }
        GROUP BY ?winner ?winnerName ?tournamentName
        ORDER BY ?winnerName ?tot
    }
}
GROUP BY ?player ?playerName ?countryForSport ?countryForSportName
HAVING (count(*) >=4)
ORDER BY asc (?all)
LIMIT 100

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('countryForSport', 'http://www.wikidata.org/entity/Q39'), ('countryForSportName', 'Switzerland'), ('all', '4')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q668'), ('countryForSportName', 'India'), ('all', '4')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q403'), ('countryForSportName', 'Serbia'), ('all', '4')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q159'), ('countryForSportName', 'Russia'), ('all', '4')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q30'), ('countryForSportName', 'United States of America'), ('all', '4')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q183'), ('countryForSportName', 'Germany'), ('all', '4')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q155'), ('countryForSportName', 'Brazil'), ('all', '4')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q31'), ('countryForSportName', 'Belgium'), ('all', '4')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q142'), ('countryForSportName', 'France'), ('all', '4')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q213'), ('countryForSportName', 'Czech Republic'), ('all', '4')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q29'), ('countryForSportName', 'Spain'), ('all', '4')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q184'), ('countryForSportName', 'Belarus'), ('all', '4')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q33946'), ('countryForSportName', 'Czechoslovakia'), ('all', '4')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q408'), ('countryForSportName', 'Australia'), ('all', '4')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q17'), ('countryForSportName', 'Japan'), ('all', '4')]
# 15

# %% [markdown]
# #### SOL 2: any subTournament is eligible count as a win in a tournament, any of 4 tournaments can be won in different year

# %%
# write your queries
# Consider the country for sport property of the tennis player (NO Country of citizenship). 
# Return the countries with at least one player who won at least one edition of each Grand Slam (the result set must be a list of country IRI and label).

# P31 ('instance of')
# P527 ('has part')
# P1346 ('winner')
# P1532 ('country for sport')

# GROUP BY ?winner & ?tournament
# ORDERING
# LIMIT extended to 100
# CREATING outer query -> prob result is incorrect, it should have atmost 4 as there are only 4 tournaments possible but 
#                         it is keeping only one row for each player from inner query
# TRYING to debug with one player specifically ('Natasha Zvereva')
# FILTER with wrong parametes, added regex
# FIND, I need to group also in the outer select
# Checking correctness, ORDER BY + HAVING, OK
# Selecting players those who won all four tournaments in GS

# GETTING countryForSport for the winners, some players has more than one countryForSport
# GETTING END result, removing wrong all


queryString = """

PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
SELECT DISTINCT ?countryForSport ?countryForSportName
WHERE {
    # ?player wdt:P1532 ?countryForSport;
            sc:name ?playerName.
    # ?countryForSport sc:name ?countryForSportName.
    FILTER (?player = ?winner)
    {
        SELECT DISTINCT ?winner ?winnerName ?tournamentName (COUNT(*) AS ?tot)
        WHERE {
           # All four tourmamets in Grand Slam
           VALUES (?tournament){
               (wd:Q43605)  # French Open
               (wd:Q123577) # US Open
               (wd:Q41520)  # Wimbledon Championships
               (wd:Q60874)  # Australian Open
           }
           # ?yearlyTournament wdt:P31 ?tournament.
           # ?yearlyTournament wdt:P527 ?subTournament.
           # ?subTournament wdt:P1346 ?winner.

           # get the label 
           # ?tournament sc:name ?tournamentName .
           # ?winner sc:name ?winnerName.
        }
        GROUP BY ?winner ?winnerName ?tournamentName
        ORDER BY ?winnerName ?tot
    }
}
GROUP BY ?player ?playerName ?countryForSport ?countryForSportName
HAVING (count(*) >=4)
LIMIT 100

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('countryForSport', 'http://www.wikidata.org/entity/Q39'), ('countryForSportName', 'Switzerland')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q668'), ('countryForSportName', 'India')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q403'), ('countryForSportName', 'Serbia')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q159'), ('countryForSportName', 'Russia')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q30'), ('countryForSportName', 'United States of America')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q183'), ('countryForSportName', 'Germany')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q155'), ('countryForSportName', 'Brazil')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q31'), ('countryForSportName', 'Belgium')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q142'), ('countryForSportName', 'France')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q213'), ('countryForSportName', 'Czech Republic')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q29'), ('countryForSportName', 'Spain')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q184'), ('countryForSportName', 'Belarus')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q33946'), ('countryForSportName', 'Czechoslovakia')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q408'), ('countryForSportName', 'Australia')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q17'), ('countryForSportName', 'Japan')]
# 15

# %% [markdown]
# ### Final query for this task:
# #### 2 different interpretation of: Return the countries with at least one player who won at least one edition of each Grand Slam

# %% [markdown]
# #### SOL 1:
#     A) All tournaments has to be won in the same year,
#     B) A player is considere if and only if he/she wins in the same category/competitionClass of every tournament

# %%
# write your final query
# Consider the country for sport property of the tennis player (NO Country of citizenship). 
# Return the countries with at least one player who won at least one edition of each Grand Slam (the result set must be a list of country IRI and label).


# P31 ('instance of')
# P527 ('has part')
# P1346 ('winner')
# P1532 ('country for sport')


queryString = """

PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
SELECT DISTINCT ?countryForSport ?countryForSportName
WHERE {
    # All four tourmamets in Grand Slam
   VALUES (?tournament){
       (wd:Q43605)  # French Open
       (wd:Q123577) # US Open
       (wd:Q41520)  # Wimbledon Championships
       (wd:Q60874)  # Australian Open
   }
   # ?yearlyTournament wdt:P31 ?tournament;
                    wdt:P527 ?subTournament.
   # ?subTournament wdt:P1346 ?winner;
                   wdt:P2094 ?competitionClass.
   
   # ?winner wdt:P1532 ?countryForSport.
   
   # get the label 
   # ?yearlyTournament sc:name ?yearlyTournamentName .
   # ?countryForSport sc:name ?countryForSportName.
   
   BIND(xsd:integer(SUBSTR(?yearlyTournamentName,0,4)) as ?year)
}
GROUP BY ?winner ?countryForSport ?countryForSportName ?competitionClass ?year
HAVING (count(*) >=4)
ORDER BY DESC (?year)
LIMIT 20

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('countryForSport', 'http://www.wikidata.org/entity/Q183'), ('countryForSportName', 'Germany')]
# 1

# %% [markdown]
# #### SOL 2:
#     A) Tournaments can be won in different year
#     B) Any win in any subTournament is eligible to count as a win in its respective tournament

# %%
# write your queries
# Consider the country for sport property of the tennis player (NO Country of citizenship). 
# Return the countries with at least one player who won at least one edition of each Grand Slam (the result set must be a list of country IRI and label).

# P31 ('instance of')
# P527 ('has part')
# P1346 ('winner')
# P1532 ('country for sport')

queryString = """

PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
# OUTER QUERY to get countryForSport of the players who won all four tournaments in GS (HAVING), no matters when
SELECT DISTINCT ?countryForSport ?countryForSportName
WHERE {
    # ?player wdt:P1532 ?countryForSport;
            sc:name ?playerName.
    # ?countryForSport sc:name ?countryForSportName.
    
    # JOINING OUTER TO INNER QUERY
    FILTER (?player = ?winner)
    {
        # INNER QUERY to get players and their wins in each tournament
        SELECT DISTINCT ?winner ?winnerName ?tournamentName (COUNT(*) AS ?tot)
        WHERE {
           # All four tourmamets in Grand Slam
           VALUES (?tournament){
               (wd:Q43605)  # French Open
               (wd:Q123577) # US Open
               (wd:Q41520)  # Wimbledon Championships
               (wd:Q60874)  # Australian Open
           }
           # ?yearlyTournament wdt:P31 ?tournament.
           # ?yearlyTournament wdt:P527 ?subTournament.
           # ?subTournament wdt:P1346 ?winner.

           # get the label 
           # ?tournament sc:name ?tournamentName .
           # ?winner sc:name ?winnerName.
        }
        GROUP BY ?winner ?winnerName ?tournamentName
        ORDER BY ?winnerName ?tot
    }
}
GROUP BY ?player ?playerName ?countryForSport ?countryForSportName
HAVING (count(*) >=4)
ORDER BY ASC (?countryForSportName)
LIMIT 100

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('countryForSport', 'http://www.wikidata.org/entity/Q408'), ('countryForSportName', 'Australia')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q184'), ('countryForSportName', 'Belarus')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q31'), ('countryForSportName', 'Belgium')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q155'), ('countryForSportName', 'Brazil')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q213'), ('countryForSportName', 'Czech Republic')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q33946'), ('countryForSportName', 'Czechoslovakia')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q142'), ('countryForSportName', 'France')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q183'), ('countryForSportName', 'Germany')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q668'), ('countryForSportName', 'India')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q17'), ('countryForSportName', 'Japan')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q159'), ('countryForSportName', 'Russia')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q403'), ('countryForSportName', 'Serbia')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q29'), ('countryForSportName', 'Spain')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q39'), ('countryForSportName', 'Switzerland')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q30'), ('countryForSportName', 'United States of America')]
# 15

# %% [markdown]
# ## Task 8
# Consider the country for sport property of the tennis player (NO Country of citizenship). Return the countries with at least one player who was ranked 1 in the tennis ranking  (the result set must be a list of country IRI and label).

# %%
# write your queries
# Consider the country for sport property of the tennis player (NO Country of citizenship). 
# Return the countries with at least one player who was ranked 1 in the tennis ranking  (the result set must be a list of country IRI and label).

# [('p', 'http://www.wikidata.org/prop/direct/P1532'), ('name', 'country for sport')]

# STARTING FROM Q1426, Roger Federer to find the ranking

queryString = """

PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
SELECT DISTINCT ?p ?pName
WHERE {
   wd:Q1426 ?p ?o .
   # get the label 
   # ?p sc:name ?pName.
   #?o sc:name ?oName.
}
LIMIT 100

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P1006'), ('pName', 'Nationale Thesaurus voor Auteurs ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P103'), ('pName', 'native language')]
# [('p', 'http://www.wikidata.org/prop/direct/P106'), ('pName', 'occupation')]
# [('p', 'http://www.wikidata.org/prop/direct/P108'), ('pName', 'employer')]
# [('p', 'http://www.wikidata.org/prop/direct/P1263'), ('pName', 'NNDB people ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1280'), ('pName', 'CONOR.SI ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1284'), ('pName', 'Munzinger person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1285'), ('pName', 'Munzinger Sport number')]
# [('p', 'http://www.wikidata.org/prop/direct/P1296'), ('pName', 'Gran Enciclopèdia Catalana ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1343'), ('pName', 'described by source')]
# [('p', 'http://www.wikidata.org/prop/direct/P1344'), ('pName', 'participant in')]
# [('p', 'http://www.wikidata.org/prop/direct/P1352'), ('pName', 'ranking')]
# [('p', 'http://www.wikidata.org/prop/direct/P140'), ('pName', 'religion')]
# [('p', 'http://www.wikidata.org/prop/direct/P1412'), ('pName', 'languages spoken, written or signed')]
# [('p', 'http://www.wikidata.org/prop/direct/P1417'), ('pName', 'Encyclopædia Britannica Online ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1447'), ('pName', 'Sports-Reference.com Olympic athlete ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1532'), ('pName', 'country for sport')]
# [('p', 'http://www.wikidata.org/prop/direct/P166'), ('pName', 'award received')]
# [('p', 'http://www.wikidata.org/prop/direct/P1695'), ('pName', 'NLP ID (unique)')]
# [('p', 'http://www.wikidata.org/prop/direct/P1741'), ('pName', 'GTAA ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P18'), ('pName', 'image')]
# [('p', 'http://www.wikidata.org/prop/direct/P19'), ('pName', 'place of birth')]
# [('p', 'http://www.wikidata.org/prop/direct/P2002'), ('pName', 'Twitter username')]
# [('p', 'http://www.wikidata.org/prop/direct/P2003'), ('pName', 'Instagram username')]
# [('p', 'http://www.wikidata.org/prop/direct/P2013'), ('pName', 'Facebook ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2019'), ('pName', 'AllMovie person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2031'), ('pName', 'work period (start)')]
# [('p', 'http://www.wikidata.org/prop/direct/P2048'), ('pName', 'height')]
# [('p', 'http://www.wikidata.org/prop/direct/P2067'), ('pName', 'mass')]
# [('p', 'http://www.wikidata.org/prop/direct/P21'), ('pName', 'sex or gender')]
# [('p', 'http://www.wikidata.org/prop/direct/P2121'), ('pName', 'prize money')]
# [('p', 'http://www.wikidata.org/prop/direct/P213'), ('pName', 'ISNI')]
# [('p', 'http://www.wikidata.org/prop/direct/P214'), ('pName', 'VIAF ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2163'), ('pName', 'FAST ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P22'), ('pName', 'father')]
# [('p', 'http://www.wikidata.org/prop/direct/P2218'), ('pName', 'net worth')]
# [('p', 'http://www.wikidata.org/prop/direct/P227'), ('pName', 'GND ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2416'), ('pName', 'sports discipline competed in')]
# [('p', 'http://www.wikidata.org/prop/direct/P244'), ('pName', 'Library of Congress authority ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P25'), ('pName', 'mother')]
# [('p', 'http://www.wikidata.org/prop/direct/P2522'), ('pName', 'victory')]
# [('p', 'http://www.wikidata.org/prop/direct/P26'), ('pName', 'spouse')]
# [('p', 'http://www.wikidata.org/prop/direct/P2604'), ('pName', 'Kinopoisk person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2605'), ('pName', 'ČSFD person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P268'), ('pName', 'Bibliothèque nationale de France ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P269'), ('pName', 'IdRef ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P27'), ('pName', 'country of citizenship')]
# [('p', 'http://www.wikidata.org/prop/direct/P286'), ('pName', 'head coach')]
# [('p', 'http://www.wikidata.org/prop/direct/P2924'), ('pName', 'Great Russian Encyclopedia Online ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('p', 'http://www.wikidata.org/prop/direct/P3171'), ('pName', 'Olympic.org athlete ID (archived version)')]
# [('p', 'http://www.wikidata.org/prop/direct/P3219'), ('pName', 'Encyclopædia Universalis ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3221'), ('pName', 'New York Times topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3222'), ('pName', 'NE.se ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3342'), ('pName', 'significant person')]
# [('p', 'http://www.wikidata.org/prop/direct/P3373'), ('pName', 'sibling')]
# [('p', 'http://www.wikidata.org/prop/direct/P3388'), ('pName', 'LittleSis people ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3417'), ('pName', 'Quora topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3427'), ('pName', 'AS.com athlete ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P345'), ('pName', 'IMDb ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3509'), ('pName', 'Dagens Nyheter topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3553'), ('pName', 'Zhihu topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3630'), ('pName', 'Babelio author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P373'), ('pName', 'Commons category')]
# [('p', 'http://www.wikidata.org/prop/direct/P3846'), ('pName', 'DBC author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P39'), ('pName', 'position held')]
# [('p', 'http://www.wikidata.org/prop/direct/P40'), ('pName', 'child')]
# [('p', 'http://www.wikidata.org/prop/direct/P4342'), ('pName', 'Store norske leksikon ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P4544'), ('pName', 'Tennis Temple player ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P463'), ('pName', 'member of')]
# [('p', 'http://www.wikidata.org/prop/direct/P4666'), ('pName', 'CineMagia person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P4789'), ('pName', "Who's Who UK ID")]
# [('p', 'http://www.wikidata.org/prop/direct/P4985'), ('pName', 'TMDb person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5019'), ('pName', 'Brockhaus Enzyklopädie online ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5034'), ('pName', 'National Library of Korea ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5247'), ('pName', 'Giant Bomb ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5337'), ('pName', 'Google News topics ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5361'), ('pName', 'BNB person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5421'), ('pName', 'Trading Card Database person ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P551'), ('pName', 'residence')]
# [('p', 'http://www.wikidata.org/prop/direct/P552'), ('pName', 'handedness')]
# [('p', 'http://www.wikidata.org/prop/direct/P555'), ('pName', 'doubles record')]
# [('p', 'http://www.wikidata.org/prop/direct/P5617'), ('pName', 'Evene ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P564'), ('pName', 'singles record')]
# [('p', 'http://www.wikidata.org/prop/direct/P569'), ('pName', 'date of birth')]
# [('p', 'http://www.wikidata.org/prop/direct/P5815'), ('pName', 'Olympics.com athlete ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P599'), ('pName', 'ITF player ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6262'), ('pName', 'Fandom article ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6327'), ('pName', 'Goodreads character ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P641'), ('pName', 'sport')]
# [('p', 'http://www.wikidata.org/prop/direct/P646'), ('pName', 'Freebase ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6553'), ('pName', 'personal pronoun')]
# [('p', 'http://www.wikidata.org/prop/direct/P6573'), ('pName', 'Klexikon article ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6656'), ('pName', 'BHCL ID (former scheme)')]
# [('p', 'http://www.wikidata.org/prop/direct/P6683'), ('pName', 'Alexander Turnbull Library ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6868'), ('pName', 'Hoopla artist ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P691'), ('pName', 'NKCR AUT ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7293'), ('pName', 'PLWABN ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P734'), ('pName', 'family name')]
# [('p', 'http://www.wikidata.org/prop/direct/P735'), ('pName', 'given name')]
# 100

# %%
# write your queries
# Consider the country for sport property of the tennis player (NO Country of citizenship). 
# Return the countries with at least one player who was ranked 1 in the tennis ranking  (the result set must be a list of country IRI and label).

# P1532 ('country for sport')

# STARTING FROM Q1426, Roger Federer to find the ranking

# found: P1352 ('ranking') ,P166 ('award received'), P2522 ('victory')

queryString = """

PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
SELECT DISTINCT ?o
WHERE {
   wd:Q1426 wdt:P1352 ?o .
   # get the label 
   #?p sc:name ?pName.
   #?o sc:name ?oName.
}
LIMIT 100

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('o', '1')]
# [('o', '24')]
# 2

# %%
# write your queries
# Consider the country for sport property of the tennis player (NO Country of citizenship). 
# Return the countries with at least one player who was ranked 1 in the tennis ranking  (the result set must be a list of country IRI and label).

# P1532 ('country for sport')

# STARTING FROM Q1426, Roger Federer to find the ranking

# found: P1352 ('ranking') ,P166 ('award received'), P2522 ('victory')

queryString = """

PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
SELECT DISTINCT ?o ?oName
WHERE {
   wd:Q1426 wdt:P166 ?o .
   # get the label 
   #?p sc:name ?pName.
   # ?o sc:name ?oName.
}
LIMIT 100

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('o', 'http://www.wikidata.org/entity/Q56509472'), ('oName', 'honorary doctor of the University of Basel')]
# [('o', 'http://www.wikidata.org/entity/Q1061233'), ('oName', "L'Équipe Champion of Champions")]
# [('o', 'http://www.wikidata.org/entity/Q338737'), ('oName', 'Swiss Sports Personality of the Year')]
# [('o', 'http://www.wikidata.org/entity/Q3494048'), ('oName', 'BBC Overseas Sports Personality of the Year')]
# [('o', 'http://www.wikidata.org/entity/Q4896696'), ('oName', 'Best International Athlete ESPY Award')]
# [('o', 'http://www.wikidata.org/entity/Q693708'), ('oName', 'ITF World Champions')]
# 6

# %%
# write your queries
# Consider the country for sport property of the tennis player (NO Country of citizenship). 
# Return the countries with at least one player who was ranked 1 in the tennis ranking  (the result set must be a list of country IRI and label).

# P1532 ('country for sport')

# STARTING FROM Q1426, Roger Federer to find the ranking

# found: P1352 ('ranking') ,P166 ('award received'), P2522 ('victory')

queryString = """

PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
SELECT DISTINCT ?o ?oName
WHERE {
   wd:Q1426 wdt:P2522 ?o .
   # get the label 
   #?p sc:name ?pName.
   # ?o sc:name ?oName.
}
LIMIT 100

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('o', 'http://www.wikidata.org/entity/Q22956224'), ('oName', "2017 Australian Open – Men's Singles")]
# [('o', 'http://www.wikidata.org/entity/Q612597'), ('oName', '2007 Tennis Masters Cup')]
# [('o', 'http://www.wikidata.org/entity/Q782589'), ('oName', "2010 Australian Open – Men's Singles")]
# [('o', 'http://www.wikidata.org/entity/Q782420'), ('oName', "2006 Australian Open – Men's Singles")]
# [('o', 'http://www.wikidata.org/entity/Q300024'), ('oName', '2011 ATP World Tour Finals')]
# [('o', 'http://www.wikidata.org/entity/Q753300'), ('oName', "2012 Wimbledon Championships – Gentlemen's Singles")]
# [('o', 'http://www.wikidata.org/entity/Q757054'), ('oName', "tennis at the 2008 Summer Olympics – men's doubles")]
# [('o', 'http://www.wikidata.org/entity/Q1074654'), ('oName', "2006 Wimbledon Championships – Men's Singles")]
# [('o', 'http://www.wikidata.org/entity/Q384929'), ('oName', "2005 Wimbledon Championships – Men's Singles")]
# [('o', 'http://www.wikidata.org/entity/Q14916861'), ('oName', '2014 Davis Cup')]
# [('o', 'http://www.wikidata.org/entity/Q46993124'), ('oName', "2018 Australian Open – Men's Singles")]
# [('o', 'http://www.wikidata.org/entity/Q964291'), ('oName', '2006 Tennis Masters Cup')]
# [('o', 'http://www.wikidata.org/entity/Q300022'), ('oName', '2010 ATP World Tour Finals')]
# [('o', 'http://www.wikidata.org/entity/Q1048953'), ('oName', "2004 US Open – Men's Singles")]
# [('o', 'http://www.wikidata.org/entity/Q731509'), ('oName', "2005 US Open – Men's Singles")]
# [('o', 'http://www.wikidata.org/entity/Q741573'), ('oName', "2009 French Open – Men's Singles")]
# [('o', 'http://www.wikidata.org/entity/Q912506'), ('oName', "2006 US Open – Men's Singles")]
# [('o', 'http://www.wikidata.org/entity/Q248965'), ('oName', "2004 Wimbledon Championships – Men's Singles")]
# [('o', 'http://www.wikidata.org/entity/Q378627'), ('oName', "2003 Wimbledon Championships – Men's Singles")]
# [('o', 'http://www.wikidata.org/entity/Q779654'), ('oName', "2004 Australian Open - men's singles")]
# [('o', 'http://www.wikidata.org/entity/Q25344123'), ('oName', "2017 Wimbledon Championships – Men's Singles")]
# [('o', 'http://www.wikidata.org/entity/Q2478340'), ('oName', '2011 BNP Paribas Masters – singles')]
# [('o', 'http://www.wikidata.org/entity/Q751798'), ('oName', "2009 Wimbledon Championships – Men's Singles")]
# [('o', 'http://www.wikidata.org/entity/Q782451'), ('oName', "2007 Australian Open – Men's Singles")]
# [('o', 'http://www.wikidata.org/entity/Q912483'), ('oName', "2007 Wimbledon Championships – Men's Singles")]
# [('o', 'http://www.wikidata.org/entity/Q304072'), ('oName', "2008 US Open – Men's Singles")]
# [('o', 'http://www.wikidata.org/entity/Q2031910'), ('oName', '2003 Tennis Masters Cup')]
# [('o', 'http://www.wikidata.org/entity/Q2094307'), ('oName', '2004 Tennis Masters Cup')]
# [('o', 'http://www.wikidata.org/entity/Q836815'), ('oName', "2007 US Open – Men's Singles")]
# 29

# %% [markdown]
# #### Finding overall ranking of each tournament

# %%
# write your queries
# Consider the country for sport property of the tennis player (NO Country of citizenship). 
# Return the countries with at least one player who was ranked 1 in the tennis ranking  (the result set must be a list of country IRI and label).

# finding overall ranking, in other ways

# Q41520 wimbledon
queryString = """

PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
SELECT DISTINCT ?p ?pName
WHERE {
   wd:Q41520 ?p ?o.
   # get the label 
   # ?p sc:name ?pName.
   #?o sc:name ?oName.
}
LIMIT 100

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity')]
# [('p', 'http://www.wikidata.org/prop/direct/P1417'), ('pName', 'Encyclopædia Britannica Online ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1424'), ('pName', "topic's main template")]
# [('p', 'http://www.wikidata.org/prop/direct/P1687'), ('pName', 'Wikidata property')]
# [('p', 'http://www.wikidata.org/prop/direct/P17'), ('pName', 'country')]
# [('p', 'http://www.wikidata.org/prop/direct/P18'), ('pName', 'image')]
# [('p', 'http://www.wikidata.org/prop/direct/P1889'), ('pName', 'different from')]
# [('p', 'http://www.wikidata.org/prop/direct/P2002'), ('pName', 'Twitter username')]
# [('p', 'http://www.wikidata.org/prop/direct/P2003'), ('pName', 'Instagram username')]
# [('p', 'http://www.wikidata.org/prop/direct/P2013'), ('pName', 'Facebook ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P214'), ('pName', 'VIAF ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2257'), ('pName', 'event interval')]
# [('p', 'http://www.wikidata.org/prop/direct/P227'), ('pName', 'GND ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2354'), ('pName', 'has list')]
# [('p', 'http://www.wikidata.org/prop/direct/P2397'), ('pName', 'YouTube channel ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P244'), ('pName', 'Library of Congress authority ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P276'), ('pName', 'location')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of')]
# [('p', 'http://www.wikidata.org/prop/direct/P2924'), ('pName', 'Great Russian Encyclopedia Online ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('p', 'http://www.wikidata.org/prop/direct/P3221'), ('pName', 'New York Times topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3417'), ('pName', 'Quora topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3479'), ('pName', 'Omni topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P361'), ('pName', 'part of')]
# [('p', 'http://www.wikidata.org/prop/direct/P373'), ('pName', 'Commons category')]
# [('p', 'http://www.wikidata.org/prop/direct/P4431'), ('pName', 'Google Doodle')]
# [('p', 'http://www.wikidata.org/prop/direct/P4622'), ('pName', 'trophy awarded')]
# [('p', 'http://www.wikidata.org/prop/direct/P571'), ('pName', 'inception')]
# [('p', 'http://www.wikidata.org/prop/direct/P641'), ('pName', 'sport')]
# [('p', 'http://www.wikidata.org/prop/direct/P646'), ('pName', 'Freebase ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P664'), ('pName', 'organizer')]
# [('p', 'http://www.wikidata.org/prop/direct/P691'), ('pName', 'NKCR AUT ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P765'), ('pName', 'surface played on')]
# [('p', 'http://www.wikidata.org/prop/direct/P7818'), ('pName', 'French Vikidia ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7859'), ('pName', 'WorldCat Identities ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7959'), ('pName', 'historic county')]
# [('p', 'http://www.wikidata.org/prop/direct/P856'), ('pName', 'official website')]
# [('p', 'http://www.wikidata.org/prop/direct/P8687'), ('pName', 'social media followers')]
# [('p', 'http://www.wikidata.org/prop/direct/P910'), ('pName', "topic's main category")]
# [('p', 'http://www.wikidata.org/prop/direct/P948'), ('pName', 'page banner')]
# 40

# %%
# write your queries
# Consider the country for sport property of the tennis player (NO Country of citizenship). 
# Return the countries with at least one player who was ranked 1 in the tennis ranking  (the result set must be a list of country IRI and label).

#finding overall ranking

# Q41520 wimbledon
queryString = """

PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
SELECT DISTINCT ?p ?pName ?o ?oName
WHERE {
   wd:Q41520 ?p ?o.
   # get the label 
   # ?p sc:name ?pName.
   # ?o sc:name ?oName.
}
LIMIT 100

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P664'), ('pName', 'organizer'), ('o', 'http://www.wikidata.org/entity/Q815369'), ('oName', 'All England Lawn Tennis and Croquet Club')]
# [('p', 'http://www.wikidata.org/prop/direct/P276'), ('pName', 'location'), ('o', 'http://www.wikidata.org/entity/Q815369'), ('oName', 'All England Lawn Tennis and Croquet Club')]
# [('p', 'http://www.wikidata.org/prop/direct/P664'), ('pName', 'organizer'), ('o', 'http://www.wikidata.org/entity/Q223041'), ('oName', 'International Tennis Federation')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q13219666'), ('oName', 'tennis tournament')]
# [('p', 'http://www.wikidata.org/prop/direct/P17'), ('pName', 'country'), ('o', 'http://www.wikidata.org/entity/Q145'), ('oName', 'United Kingdom')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('o', 'http://www.wikidata.org/entity/Q18608583'), ('oName', 'recurring sporting event')]
# [('p', 'http://www.wikidata.org/prop/direct/P641'), ('pName', 'sport'), ('o', 'http://www.wikidata.org/entity/Q847'), ('oName', 'tennis')]
# [('p', 'http://www.wikidata.org/prop/direct/P765'), ('pName', 'surface played on'), ('o', 'http://www.wikidata.org/entity/Q1151291'), ('oName', 'grass court')]
# [('p', 'http://www.wikidata.org/prop/direct/P7959'), ('pName', 'historic county'), ('o', 'http://www.wikidata.org/entity/Q67443130'), ('oName', 'Surrey')]
# [('p', 'http://www.wikidata.org/prop/direct/P361'), ('pName', 'part of'), ('o', 'http://www.wikidata.org/entity/Q102113'), ('oName', 'Grand Slam of tennis')]
# [('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q736742'), ('oName', 'Wimbledon')]
# [('p', 'http://www.wikidata.org/prop/direct/P664'), ('pName', 'organizer'), ('o', 'http://www.wikidata.org/entity/Q1337913'), ('oName', 'Lawn Tennis Association')]
# [('p', 'http://www.wikidata.org/prop/direct/P2354'), ('pName', 'has list'), ('o', 'http://www.wikidata.org/entity/Q6585893'), ('oName', 'list of Wimbledon singles finalists during the open era')]
# [('p', 'http://www.wikidata.org/prop/direct/P1687'), ('pName', 'Wikidata property'), ('o', 'http://www.wikidata.org/entity/P4503'), ('oName', 'Wimbledon player ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1424'), ('pName', "topic's main template"), ('o', 'http://www.wikidata.org/entity/Q43323825'), ('oName', 'Template:Wimbledon player')]
# [('p', 'http://www.wikidata.org/prop/direct/P1889'), ('pName', 'different from'), ('o', 'http://www.wikidata.org/entity/Q206375'), ('oName', 'Wimbledon')]
# [('p', 'http://www.wikidata.org/prop/direct/P910'), ('pName', "topic's main category"), ('o', 'http://www.wikidata.org/entity/Q5326534'), ('oName', 'Category:The Championships, Wimbledon')]
# [('p', 'http://www.wikidata.org/prop/direct/P4622'), ('pName', 'trophy awarded'), ('o', 'http://www.wikidata.org/entity/Q7920608'), ('oName', 'Venus Rosewater Dish')]
# 18

# %%
# write your queries
# Consider the country for sport property of the tennis player (NO Country of citizenship). 
# Return the countries with at least one player who was ranked 1 in the tennis ranking  (the result set must be a list of country IRI and label).

#finding overall ranking

# Q41520 wimbledon
# [('p', 'http://www.wikidata.org/prop/direct/P361'), ('pName', 'part of'), ('o', 'http://www.wikidata.org/entity/Q102113'), ('oName', 'Grand Slam of tennis')]
queryString = """

PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
SELECT DISTINCT ?p ?pName #?o ?oName
WHERE {
   wd:Q102113 ?p ?o.
   # get the label 
   # ?p sc:name ?pName.
   #?o sc:name ?oName.
}
LIMIT 100

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P1417'), ('pName', 'Encyclopædia Britannica Online ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1424'), ('pName', "topic's main template")]
# [('p', 'http://www.wikidata.org/prop/direct/P18'), ('pName', 'image')]
# [('p', 'http://www.wikidata.org/prop/direct/P2354'), ('pName', 'has list')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of')]
# [('p', 'http://www.wikidata.org/prop/direct/P2924'), ('pName', 'Great Russian Encyclopedia Online ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of')]
# [('p', 'http://www.wikidata.org/prop/direct/P3222'), ('pName', 'NE.se ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3417'), ('pName', 'Quora topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P373'), ('pName', 'Commons category')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part')]
# [('p', 'http://www.wikidata.org/prop/direct/P641'), ('pName', 'sport')]
# [('p', 'http://www.wikidata.org/prop/direct/P646'), ('pName', 'Freebase ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8408'), ('pName', 'KBpedia ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P910'), ('pName', "topic's main category")]
# 15

# %%
# write your queries
# Consider the country for sport property of the tennis player (NO Country of citizenship). 
# Return the countries with at least one player who was ranked 1 in the tennis ranking  (the result set must be a list of country IRI and label).

#finding overall ranking

# Q41520 wimbledon
# [('p', 'http://www.wikidata.org/prop/direct/P361'), ('pName', 'part of'), ('o', 'http://www.wikidata.org/entity/Q102113'), ('oName', 'Grand Slam of tennis')]
queryString = """

PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
SELECT DISTINCT ?p ?pName ?o ?oName
WHERE {
   wd:Q102113 ?p ?o.
   # get the label 
   # ?p sc:name ?pName.
   # ?o sc:name ?oName.
}
LIMIT 100

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('o', 'http://www.wikidata.org/entity/Q50301185'), ('oName', 'tennis tour with multiple editions')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q7700500'), ('oName', 'tennis tour')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('o', 'http://www.wikidata.org/entity/Q2223649'), ('oName', 'French cheese')]
# [('p', 'http://www.wikidata.org/prop/direct/P1424'), ('pName', "topic's main template"), ('o', 'http://www.wikidata.org/entity/Q5851433'), ('oName', 'Template:Infobox GrandSlamTournaments')]
# [('p', 'http://www.wikidata.org/prop/direct/P641'), ('pName', 'sport'), ('o', 'http://www.wikidata.org/entity/Q847'), ('oName', 'tennis')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('o', 'http://www.wikidata.org/entity/Q123577'), ('oName', 'US Open')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('o', 'http://www.wikidata.org/entity/Q41520'), ('oName', 'Wimbledon Championships')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('o', 'http://www.wikidata.org/entity/Q60874'), ('oName', 'Australian Open')]
# [('p', 'http://www.wikidata.org/prop/direct/P2354'), ('pName', 'has list'), ('o', 'http://www.wikidata.org/entity/Q1426439'), ('oName', "list of Grand Slam men's singles champions")]
# [('p', 'http://www.wikidata.org/prop/direct/P910'), ('pName', "topic's main category"), ('o', 'http://www.wikidata.org/entity/Q18156144'), ('oName', 'Category:Grand Slam (tennis)')]
# [('p', 'http://www.wikidata.org/prop/direct/P2354'), ('pName', 'has list'), ('o', 'http://www.wikidata.org/entity/Q645455'), ('oName', "list of Grand Slam women's singles champions")]
# 11

# %%
# write your queries
# Consider the country for sport property of the tennis player (NO Country of citizenship). 
# Return the countries with at least one player who was ranked 1 in the tennis ranking  (the result set must be a list of country IRI and label).

#finding overall ranking

# Q41520 wimbledon
# [('p', 'http://www.wikidata.org/prop/direct/P361'), ('pName', 'part of'), ('o', 'http://www.wikidata.org/entity/Q102113'), ('oName', 'Grand Slam of tennis')]
queryString = """

PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
SELECT DISTINCT ?list ?listName ?p ?pName ?o ?oName
WHERE {
   wd:Q102113 wdt:P2354 ?list.
   # ?list ?p ?o.
   # get the label 
   # ?p sc:name ?pName.
   # ?o sc:name ?oName.
}
LIMIT 100

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('list', 'http://www.wikidata.org/entity/Q645455'), ('p', 'http://www.wikidata.org/prop/direct/P2094'), ('pName', 'competition class'), ('o', 'http://www.wikidata.org/entity/Q16893403'), ('oName', "women's singles")]
# [('list', 'http://www.wikidata.org/entity/Q1426439'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('o', 'http://www.wikidata.org/entity/Q13406463'), ('oName', 'Wikimedia list article')]
# [('list', 'http://www.wikidata.org/entity/Q645455'), ('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('o', 'http://www.wikidata.org/entity/Q13406463'), ('oName', 'Wikimedia list article')]
# [('list', 'http://www.wikidata.org/entity/Q645455'), ('p', 'http://www.wikidata.org/prop/direct/P360'), ('pName', 'is a list of'), ('o', 'http://www.wikidata.org/entity/Q5'), ('oName', 'human')]
# [('list', 'http://www.wikidata.org/entity/Q1426439'), ('p', 'http://www.wikidata.org/prop/direct/P641'), ('pName', 'sport'), ('o', 'http://www.wikidata.org/entity/Q847'), ('oName', 'tennis')]
# [('list', 'http://www.wikidata.org/entity/Q645455'), ('p', 'http://www.wikidata.org/prop/direct/P641'), ('pName', 'sport'), ('o', 'http://www.wikidata.org/entity/Q847'), ('oName', 'tennis')]
# [('list', 'http://www.wikidata.org/entity/Q1426439'), ('p', 'http://www.wikidata.org/prop/direct/P2094'), ('pName', 'competition class'), ('o', 'http://www.wikidata.org/entity/Q16893072'), ('oName', "men's singles")]
# [('list', 'http://www.wikidata.org/entity/Q645455'), ('p', 'http://www.wikidata.org/prop/direct/P1754'), ('pName', 'category related to list'), ('o', 'http://www.wikidata.org/entity/Q8498722'), ('oName', "Category:Grand Slam (tennis) champions in women's singles")]
# [('list', 'http://www.wikidata.org/entity/Q1426439'), ('p', 'http://www.wikidata.org/prop/direct/P1754'), ('pName', 'category related to list'), ('o', 'http://www.wikidata.org/entity/Q8498719'), ('oName', "Category:Grand Slam (tennis) champions in men's singles")]
# 9

# %%
# write your queries
# Consider the country for sport property of the tennis player (NO Country of citizenship). 
# Return the countries with at least one player who was ranked 1 in the tennis ranking  (the result set must be a list of country IRI and label).

#finding overall ranking

# Q41520 wimbledon
# [('p', 'http://www.wikidata.org/prop/direct/P361'), ('pName', 'part of'), ('o', 'http://www.wikidata.org/entity/Q102113'), ('oName', 'Grand Slam of tennis')]
queryString = """

PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
SELECT DISTINCT  ?s ?sName ?p ?pName ?list ?listName 
WHERE {
   wd:Q102113 wdt:P2354 ?list.
   # BACKWARD
   # ?s ?p ?list.
   # get the label 
   # ?p sc:name ?pName.
   # ?s sc:name ?sName.
}
LIMIT 100

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('s', 'http://www.wikidata.org/entity/Q102113'), ('sName', 'Grand Slam of tennis'), ('p', 'http://www.wikidata.org/prop/direct/P2354'), ('pName', 'has list'), ('list', 'http://www.wikidata.org/entity/Q645455')]
# [('s', 'http://www.wikidata.org/entity/Q102113'), ('sName', 'Grand Slam of tennis'), ('p', 'http://www.wikidata.org/prop/direct/P2354'), ('pName', 'has list'), ('list', 'http://www.wikidata.org/entity/Q1426439')]
# [('s', 'http://www.wikidata.org/entity/Q8498722'), ('sName', "Category:Grand Slam (tennis) champions in women's singles"), ('p', 'http://www.wikidata.org/prop/direct/P1753'), ('pName', 'list related to category'), ('list', 'http://www.wikidata.org/entity/Q645455')]
# [('s', 'http://www.wikidata.org/entity/Q8498719'), ('sName', "Category:Grand Slam (tennis) champions in men's singles"), ('p', 'http://www.wikidata.org/prop/direct/P1753'), ('pName', 'list related to category'), ('list', 'http://www.wikidata.org/entity/Q1426439')]
# 4

# %%
# write your queries
# Consider the country for sport property of the tennis player (NO Country of citizenship). 
# Return the countries with at least one player who was ranked 1 in the tennis ranking  (the result set must be a list of country IRI and label).

#finding overall ranking

# Q41520 wimbledon
# [('p', 'http://www.wikidata.org/prop/direct/P361'), ('pName', 'part of'), ('o', 'http://www.wikidata.org/entity/Q102113'), ('oName', 'Grand Slam of tennis')]
queryString = """

PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
SELECT DISTINCT  ?p ?pName ?o
WHERE {
   wd:Q1426439 ?p ?o.
   # get the label 
   # ?p sc:name ?pName.
   #?s sc:name ?sName.
}
LIMIT 100

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P1754'), ('pName', 'category related to list'), ('o', 'http://www.wikidata.org/entity/Q8498719')]
# [('p', 'http://www.wikidata.org/prop/direct/P2094'), ('pName', 'competition class'), ('o', 'http://www.wikidata.org/entity/Q16893072')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('o', 'http://www.wikidata.org/entity/Q13406463')]
# [('p', 'http://www.wikidata.org/prop/direct/P641'), ('pName', 'sport'), ('o', 'http://www.wikidata.org/entity/Q847')]
# 4

# %%
# write your queries
# Consider the country for sport property of the tennis player (NO Country of citizenship). 
# Return the countries with at least one player who was ranked 1 in the tennis ranking  (the result set must be a list of country IRI and label).

#finding overall ranking

# Q41520 wimbledon
# [('p', 'http://www.wikidata.org/prop/direct/P361'), ('pName', 'part of'), ('o', 'http://www.wikidata.org/entity/Q102113'), ('oName', 'Grand Slam of tennis')]
queryString = """

PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
SELECT DISTINCT  ?p ?pName ?o ?oName 
WHERE {
   wd:Q1426439 ?p ?o.
   # get the label 
   # ?p sc:name ?pName.
   # ?o sc:name ?oName.
}
LIMIT 100

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('o', 'http://www.wikidata.org/entity/Q13406463'), ('oName', 'Wikimedia list article')]
# [('p', 'http://www.wikidata.org/prop/direct/P641'), ('pName', 'sport'), ('o', 'http://www.wikidata.org/entity/Q847'), ('oName', 'tennis')]
# [('p', 'http://www.wikidata.org/prop/direct/P2094'), ('pName', 'competition class'), ('o', 'http://www.wikidata.org/entity/Q16893072'), ('oName', "men's singles")]
# [('p', 'http://www.wikidata.org/prop/direct/P1754'), ('pName', 'category related to list'), ('o', 'http://www.wikidata.org/entity/Q8498719'), ('oName', "Category:Grand Slam (tennis) champions in men's singles")]
# 4

# %%
# write your queries
# Consider the country for sport property of the tennis player (NO Country of citizenship). 
# Return the countries with at least one player who was ranked 1 in the tennis ranking  (the result set must be a list of country IRI and label).

#finding overall ranking

# Q41520 wimbledon
queryString = """

PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
SELECT DISTINCT  ?p ?pName ?o ?oName 
WHERE {
   wd:Q41520 ?p ?o.
   # get the label 
   # ?p sc:name ?pName.
   OPTIONAL { ?o sc:name ?oName }.
}
LIMIT 100

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P664'), ('pName', 'organizer'), ('o', 'http://www.wikidata.org/entity/Q815369'), ('oName', 'All England Lawn Tennis and Croquet Club')]
# [('p', 'http://www.wikidata.org/prop/direct/P276'), ('pName', 'location'), ('o', 'http://www.wikidata.org/entity/Q815369'), ('oName', 'All England Lawn Tennis and Croquet Club')]
# [('p', 'http://www.wikidata.org/prop/direct/P664'), ('pName', 'organizer'), ('o', 'http://www.wikidata.org/entity/Q223041'), ('oName', 'International Tennis Federation')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q13219666'), ('oName', 'tennis tournament')]
# [('p', 'http://www.wikidata.org/prop/direct/P17'), ('pName', 'country'), ('o', 'http://www.wikidata.org/entity/Q145'), ('oName', 'United Kingdom')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('o', 'http://www.wikidata.org/entity/Q18608583'), ('oName', 'recurring sporting event')]
# [('p', 'http://www.wikidata.org/prop/direct/P641'), ('pName', 'sport'), ('o', 'http://www.wikidata.org/entity/Q847'), ('oName', 'tennis')]
# [('p', 'http://www.wikidata.org/prop/direct/P765'), ('pName', 'surface played on'), ('o', 'http://www.wikidata.org/entity/Q1151291'), ('oName', 'grass court')]
# [('p', 'http://www.wikidata.org/prop/direct/P7959'), ('pName', 'historic county'), ('o', 'http://www.wikidata.org/entity/Q67443130'), ('oName', 'Surrey')]
# [('p', 'http://www.wikidata.org/prop/direct/P361'), ('pName', 'part of'), ('o', 'http://www.wikidata.org/entity/Q102113'), ('oName', 'Grand Slam of tennis')]
# [('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q736742'), ('oName', 'Wimbledon')]
# [('p', 'http://www.wikidata.org/prop/direct/P664'), ('pName', 'organizer'), ('o', 'http://www.wikidata.org/entity/Q1337913'), ('oName', 'Lawn Tennis Association')]
# [('p', 'http://www.wikidata.org/prop/direct/P2354'), ('pName', 'has list'), ('o', 'http://www.wikidata.org/entity/Q6585893'), ('oName', 'list of Wimbledon singles finalists during the open era')]
# [('p', 'http://www.wikidata.org/prop/direct/P1687'), ('pName', 'Wikidata property'), ('o', 'http://www.wikidata.org/entity/P4503'), ('oName', 'Wimbledon player ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1424'), ('pName', "topic's main template"), ('o', 'http://www.wikidata.org/entity/Q43323825'), ('oName', 'Template:Wimbledon player')]
# [('p', 'http://www.wikidata.org/prop/direct/P1889'), ('pName', 'different from'), ('o', 'http://www.wikidata.org/entity/Q206375'), ('oName', 'Wimbledon')]
# [('p', 'http://www.wikidata.org/prop/direct/P910'), ('pName', "topic's main category"), ('o', 'http://www.wikidata.org/entity/Q5326534'), ('oName', 'Category:The Championships, Wimbledon')]
# [('p', 'http://www.wikidata.org/prop/direct/P4622'), ('pName', 'trophy awarded'), ('o', 'http://www.wikidata.org/entity/Q7920608'), ('oName', 'Venus Rosewater Dish')]
# [('p', 'http://www.wikidata.org/prop/direct/P1417'), ('pName', 'Encyclopædia Britannica Online ID'), ('o', 'sports/Wimbledon-Championships')]
# [('p', 'http://www.wikidata.org/prop/direct/P18'), ('pName', 'image'), ('o', 'http://commons.wikimedia.org/wiki/Special:FilePath/Wimbledon%20Court%201.jpg')]
# [('p', 'http://www.wikidata.org/prop/direct/P2002'), ('pName', 'Twitter username'), ('o', 'Wimbledon')]
# [('p', 'http://www.wikidata.org/prop/direct/P2003'), ('pName', 'Instagram username'), ('o', 'wimbledon')]
# [('p', 'http://www.wikidata.org/prop/direct/P2013'), ('pName', 'Facebook ID'), ('o', 'wimbledon')]
# [('p', 'http://www.wikidata.org/prop/direct/P214'), ('pName', 'VIAF ID'), ('o', '261278845')]
# [('p', 'http://www.wikidata.org/prop/direct/P2257'), ('pName', 'event interval'), ('o', '1')]
# [('p', 'http://www.wikidata.org/prop/direct/P227'), ('pName', 'GND ID'), ('o', '4191833-2')]
# [('p', 'http://www.wikidata.org/prop/direct/P2397'), ('pName', 'YouTube channel ID'), ('o', 'UCNa8NxMgSm7m4Ii9d4QGk1Q')]
# [('p', 'http://www.wikidata.org/prop/direct/P244'), ('pName', 'Library of Congress authority ID'), ('o', 'n99043286')]
# [('p', 'http://www.wikidata.org/prop/direct/P2924'), ('pName', 'Great Russian Encyclopedia Online ID'), ('o', '4216977')]
# [('p', 'http://www.wikidata.org/prop/direct/P3221'), ('pName', 'New York Times topic ID'), ('o', 'subject/wimbledon')]
# [('p', 'http://www.wikidata.org/prop/direct/P3417'), ('pName', 'Quora topic ID'), ('o', 'Wimbledon-Championships')]
# [('p', 'http://www.wikidata.org/prop/direct/P3479'), ('pName', 'Omni topic ID'), ('o', 'c5ac3ccb-e6b7-4eff-a4f6-e33453b2f60e')]
# [('p', 'http://www.wikidata.org/prop/direct/P373'), ('pName', 'Commons category'), ('o', 'Wimbledon Championships')]
# [('p', 'http://www.wikidata.org/prop/direct/P4431'), ('pName', 'Google Doodle'), ('o', '140th-anniversary-of-wimbledon')]
# [('p', 'http://www.wikidata.org/prop/direct/P571'), ('pName', 'inception'), ('o', '1877-01-01T00:00:00Z')]
# [('p', 'http://www.wikidata.org/prop/direct/P646'), ('pName', 'Freebase ID'), ('o', '/m/0mmmt')]
# [('p', 'http://www.wikidata.org/prop/direct/P691'), ('pName', 'NKCR AUT ID'), ('o', 'kn20120713006')]
# [('p', 'http://www.wikidata.org/prop/direct/P7818'), ('pName', 'French Vikidia ID'), ('o', 'Tournoi_de_Wimbledon')]
# [('p', 'http://www.wikidata.org/prop/direct/P7859'), ('pName', 'WorldCat Identities ID'), ('o', 'lccn-n99043286')]
# [('p', 'http://www.wikidata.org/prop/direct/P856'), ('pName', 'official website'), ('o', 'http://www.wimbledon.com')]
# [('p', 'http://www.wikidata.org/prop/direct/P8687'), ('pName', 'social media followers'), ('o', '788000')]
# [('p', 'http://www.wikidata.org/prop/direct/P8687'), ('pName', 'social media followers'), ('o', '3738654')]
# [('p', 'http://www.wikidata.org/prop/direct/P948'), ('pName', 'page banner'), ('o', 'http://commons.wikimedia.org/wiki/Special:FilePath/Wimbledon%20Banner.jpg')]
# 43

# %%
# write your queries
# Consider the country for sport property of the tennis player (NO Country of citizenship). 
# Return the countries with at least one player who was ranked 1 in the tennis ranking  (the result set must be a list of country IRI and label).

#finding overall ranking

# Q41520 wimbledon
queryString = """

PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
SELECT DISTINCT  ?p ?pName ?o ?oName 
WHERE {
   wd:Q13219666 ?p ?o.
   # get the label 
   # ?p sc:name ?pName.
   OPTIONAL { ?o sc:name ?oName }.
}
LIMIT 100

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q13406554'), ('oName', 'sports competition')]
# [('p', 'http://www.wikidata.org/prop/direct/P641'), ('pName', 'sport'), ('o', 'http://www.wikidata.org/entity/Q847'), ('oName', 'tennis')]
# [('p', 'http://www.wikidata.org/prop/direct/P2670'), ('pName', 'has parts of the class'), ('o', 'http://www.wikidata.org/entity/Q46190676'), ('oName', 'tennis event')]
# [('p', 'http://www.wikidata.org/prop/direct/P1424'), ('pName', "topic's main template"), ('o', 'http://www.wikidata.org/entity/Q6452600'), ('oName', 'Template:ATP Tournament')]
# [('p', 'http://www.wikidata.org/prop/direct/P2354'), ('pName', 'has list'), ('o', 'http://www.wikidata.org/entity/Q6642846'), ('oName', 'list of tennis tournaments')]
# [('p', 'http://www.wikidata.org/prop/direct/P1424'), ('pName', "topic's main template"), ('o', 'http://www.wikidata.org/entity/Q7474005'), ('oName', 'Template:Infobox tennis tournament year')]
# [('p', 'http://www.wikidata.org/prop/direct/P1424'), ('pName', "topic's main template"), ('o', 'http://www.wikidata.org/entity/Q22803873'), ('oName', 'Template:WTA tournament')]
# [('p', 'http://www.wikidata.org/prop/direct/P910'), ('pName', "topic's main category"), ('o', 'http://www.wikidata.org/entity/Q5325422'), ('oName', 'Category:Tennis tournaments')]
# [('p', 'http://www.wikidata.org/prop/direct/P1424'), ('pName', "topic's main template"), ('o', 'http://www.wikidata.org/entity/Q10810031'), ('oName', 'Template:Infobox ATP Challenger Tournament')]
# [('p', 'http://www.wikidata.org/prop/direct/P1225'), ('pName', 'U.S. National Archives Identifier'), ('o', '10663368')]
# [('p', 'http://www.wikidata.org/prop/direct/P1424'), ('pName', "topic's main template"), ('o', 'http://www.wikidata.org/entity/Q13489093')]
# [('p', 'http://www.wikidata.org/prop/direct/P1709'), ('pName', 'equivalent class'), ('o', 'http://dbpedia.org/ontology/TennisTournament')]
# [('p', 'http://www.wikidata.org/prop/direct/P8408'), ('pName', 'KBpedia ID'), ('o', 'TennisTournament')]
# 13

# %%
# write your queries
# Consider the country for sport property of the tennis player (NO Country of citizenship). 
# Return the countries with at least one player who was ranked 1 in the tennis ranking  (the result set must be a list of country IRI and label).

#finding overall ranking

# Q41520 wimbledon
queryString = """

PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
SELECT DISTINCT  ?p ?pName ?o ?oName 
WHERE {
   wd:Q6642846 ?p ?o.
   # get the label 
   # ?p sc:name ?pName.
   OPTIONAL { ?o sc:name ?oName }.
}
LIMIT 100

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P360'), ('pName', 'is a list of'), ('o', 'http://www.wikidata.org/entity/Q13219666'), ('oName', 'tennis tournament')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('o', 'http://www.wikidata.org/entity/Q13406463'), ('oName', 'Wikimedia list article')]
# [('p', 'http://www.wikidata.org/prop/direct/P641'), ('pName', 'sport'), ('o', 'http://www.wikidata.org/entity/Q847'), ('oName', 'tennis')]
# [('p', 'http://www.wikidata.org/prop/direct/P373'), ('pName', 'Commons category'), ('o', 'Tennis tournaments')]
# 4

# %%
# write your queries
# Consider the country for sport property of the tennis player (NO Country of citizenship). 
# Return the countries with at least one player who was ranked 1 in the tennis ranking  (the result set must be a list of country IRI and label).

#finding overall ranking

# Q41520 wimbledon
queryString = """

PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
SELECT DISTINCT  ?p ?pName ?o ?oName 
WHERE {
   wd:Q6452600 ?p ?o.
   # get the label 
   # ?p sc:name ?pName.
   OPTIONAL { ?o sc:name ?oName }.
}
LIMIT 100

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('o', 'http://www.wikidata.org/entity/Q11266439'), ('oName', 'Wikimedia template')]
# [('p', 'http://www.wikidata.org/prop/direct/P1423'), ('pName', 'template has topic'), ('o', 'http://www.wikidata.org/entity/Q13219666'), ('oName', 'tennis tournament')]
# [('p', 'http://www.wikidata.org/prop/direct/P1423'), ('pName', 'template has topic'), ('o', 'http://www.wikidata.org/entity/Q744089'), ('oName', 'Association of Tennis Professionals')]
# [('p', 'http://www.wikidata.org/prop/direct/P1687'), ('pName', 'Wikidata property'), ('o', 'http://www.wikidata.org/entity/P3456'), ('oName', 'ATP tennis tournament ID')]
# 4

# %%
# write your queries
# Consider the country for sport property of the tennis player (NO Country of citizenship). 
# Return the countries with at least one player who was ranked 1 in the tennis ranking  (the result set must be a list of country IRI and label).

#finding overall ranking

# Q41520 wimbledon
queryString = """

PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
SELECT DISTINCT  ?p ?pName ?o ?oName 
WHERE {
   wd:Q13219666 ?p ?o.
   # get the label 
   # ?p sc:name ?pName.
   OPTIONAL { ?o sc:name ?oName }.
}
LIMIT 100

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q13406554'), ('oName', 'sports competition')]
# [('p', 'http://www.wikidata.org/prop/direct/P641'), ('pName', 'sport'), ('o', 'http://www.wikidata.org/entity/Q847'), ('oName', 'tennis')]
# [('p', 'http://www.wikidata.org/prop/direct/P2670'), ('pName', 'has parts of the class'), ('o', 'http://www.wikidata.org/entity/Q46190676'), ('oName', 'tennis event')]
# [('p', 'http://www.wikidata.org/prop/direct/P1424'), ('pName', "topic's main template"), ('o', 'http://www.wikidata.org/entity/Q6452600'), ('oName', 'Template:ATP Tournament')]
# [('p', 'http://www.wikidata.org/prop/direct/P2354'), ('pName', 'has list'), ('o', 'http://www.wikidata.org/entity/Q6642846'), ('oName', 'list of tennis tournaments')]
# [('p', 'http://www.wikidata.org/prop/direct/P1424'), ('pName', "topic's main template"), ('o', 'http://www.wikidata.org/entity/Q7474005'), ('oName', 'Template:Infobox tennis tournament year')]
# [('p', 'http://www.wikidata.org/prop/direct/P1424'), ('pName', "topic's main template"), ('o', 'http://www.wikidata.org/entity/Q22803873'), ('oName', 'Template:WTA tournament')]
# [('p', 'http://www.wikidata.org/prop/direct/P910'), ('pName', "topic's main category"), ('o', 'http://www.wikidata.org/entity/Q5325422'), ('oName', 'Category:Tennis tournaments')]
# [('p', 'http://www.wikidata.org/prop/direct/P1424'), ('pName', "topic's main template"), ('o', 'http://www.wikidata.org/entity/Q10810031'), ('oName', 'Template:Infobox ATP Challenger Tournament')]
# [('p', 'http://www.wikidata.org/prop/direct/P1225'), ('pName', 'U.S. National Archives Identifier'), ('o', '10663368')]
# [('p', 'http://www.wikidata.org/prop/direct/P1424'), ('pName', "topic's main template"), ('o', 'http://www.wikidata.org/entity/Q13489093')]
# [('p', 'http://www.wikidata.org/prop/direct/P1709'), ('pName', 'equivalent class'), ('o', 'http://dbpedia.org/ontology/TennisTournament')]
# [('p', 'http://www.wikidata.org/prop/direct/P8408'), ('pName', 'KBpedia ID'), ('o', 'TennisTournament')]
# 13

# %%
# write your queries
# Consider the country for sport property of the tennis player (NO Country of citizenship). 
# Return the countries with at least one player who was ranked 1 in the tennis ranking  (the result set must be a list of country IRI and label).

#finding overall ranking

# Q41520 wimbledon
queryString = """

PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
SELECT DISTINCT  ?p ?pName ?o ?oName 
WHERE {
   wd:Q6642846 ?p ?o.
   # get the label 
   # ?p sc:name ?pName.
   OPTIONAL { ?o sc:name ?oName }.
}
LIMIT 100

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P360'), ('pName', 'is a list of'), ('o', 'http://www.wikidata.org/entity/Q13219666'), ('oName', 'tennis tournament')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('o', 'http://www.wikidata.org/entity/Q13406463'), ('oName', 'Wikimedia list article')]
# [('p', 'http://www.wikidata.org/prop/direct/P641'), ('pName', 'sport'), ('o', 'http://www.wikidata.org/entity/Q847'), ('oName', 'tennis')]
# [('p', 'http://www.wikidata.org/prop/direct/P373'), ('pName', 'Commons category'), ('o', 'Tennis tournaments')]
# 4

# %%
# write your queries
# Consider the country for sport property of the tennis player (NO Country of citizenship). 
# Return the countries with at least one player who was ranked 1 in the tennis ranking  (the result set must be a list of country IRI and label).

#finding overall ranking

# Q41520 wimbledon
queryString = """

PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
SELECT DISTINCT  ?p ?pName ?o ?oName 
WHERE {
   # ?o ?p wd:Q13219666 .
   # get the label 
   # ?p sc:name ?pName.
   OPTIONAL { ?o sc:name ?oName }.
}
LIMIT 100

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q299931'), ('oName', 'Chile Open')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('o', 'http://www.wikidata.org/entity/Q299384'), ('oName', 'Delray Beach International Tennis Championships')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q1961762'), ('oName', 'Mersin Cup')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q2415348'), ('oName', 'Masters France')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q3935780'), ('oName', 'Rijeka Open')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q3954502'), ('oName', 'Seguros Bolívar Open Cali')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q558006'), ('oName', 'Burnie International')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q768991'), ('oName', 'Morocco Tennis Tour – Marrakech')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q15729796'), ('oName', 'State Bank of India ATP Challenger Tour')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q3883186'), ('oName', 'Open GDF Suez de Marseille')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('o', 'http://www.wikidata.org/entity/Q16859467'), ('oName', '2014 Heilbronner Neckarcup')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q17306815'), ('oName', 'USTA Player Development Classic')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q17333197'), ('oName', 'Femenil Mérida Circuit')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q17333223'), ('oName', 'UTF Cup')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q17461001'), ('oName', 'Tennis at the Far Eastern Games')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q17464028'), ('oName', "ITF Women's Circuit – Wuhan")]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q13528155'), ('oName', "ITF Women's Circuit UBS Thurgau")]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q17493278'), ('oName', 'International Tennis Tournament of Cortina')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q24911704'), ('oName', 'Zhengzhou Open')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q22235842'), ('oName', 'Manila Challenger')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q22919781'), ('oName', 'Los Cabos Open')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('o', 'http://www.wikidata.org/entity/Q24184878'), ('oName', '2016 MercedesCup')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q26268650'), ('oName', 'ZS-Sports China International Challenger')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q26307058'), ('oName', 'Adriatic Challenger')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q50470152'), ('oName', 'BMW AHG Cup')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q27220048'), ('oName', 'Stockton ATP Challenger')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q20010797'), ('oName', 'Internazionali di Tennis Città di Vicenza')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q20127833'), ('oName', 'Aegon Ilkley Trophy')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q3088894'), ('oName', "NCAA Men's Tennis Championship")]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q1044168'), ('oName', 'World TeamTennis')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q535453'), ('oName', 'Springfield Lasers')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q539784'), ('oName', 'Maybelline Classic')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q137959'), ('oName', 'Open de Rennes')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q203273'), ('oName', 'Connecticut Open')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q299256'), ('oName', 'JSM Challenger of Champaign–Urbana')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q299531'), ('oName', 'Los Angeles Open (tennis)')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q331570'), ('oName', 'Hopman Cup')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('o', 'http://www.wikidata.org/entity/Q331570'), ('oName', 'Hopman Cup')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q3800198'), ('oName', 'Internazionali Tennis Val Gardena Südtirol')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q595467'), ('oName', 'Canadian Open')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q7179488'), ('oName', 'Peugeot Tennis Cup')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q299496'), ('oName', 'Austrian Open Kitzbühel')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q299740'), ('oName', 'St. Petersburg Open')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q584646'), ('oName', 'Texas Tennis Open')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q1765968'), ('oName', 'The Hague Open')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q1765993'), ('oName', 'Open de Tenis Ciudad de Pozoblanco Covap Memorial - Fabián Dorado')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q299541'), ('oName', 'Manchester Open')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q97670098'), ('oName', 'Brasil Open')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q121702'), ('oName', 'China Open')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q13360734'), ('oName', 'Avon Championships of Cincinnati')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q2425642'), ('oName', 'Belgian Open')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q299729'), ('oName', "Singapore Open (men's tennis)")]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q3353485'), ('oName', 'Denver Open')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q50549266'), ('oName', "tennis at the People's Republic of China National Games")]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q627279'), ('oName', 'Rio Quente Resorts Tennis Classic')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q3979465'), ('oName', 'TEAN International')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q716943'), ('oName', 'Aegon GB Pro-Series Barnstaple')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q15144568'), ('oName', 'Soho Square Ladies Tournament')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('o', 'http://www.wikidata.org/entity/Q19946263'), ('oName', '2015 Heilbronner Neckarcup')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q21055686'), ('oName', 'Columbus Challenger')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q47487971'), ('oName', 'Calgary Challenger')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q21336943'), ('oName', 'Hua Hin Championships')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q15502507'), ('oName', 'Rio Open')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q2999429'), ('oName', 'Aberavon Cup')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q3534738'), ('oName', 'Guildford Tournament')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q28739880'), ('oName', 'Eastern Mediterranean Championship Tennis')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('o', 'http://www.wikidata.org/entity/Q23748137'), ('oName', 'tennis at the 2016 Summer Olympics – mixed doubles')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q299126'), ('oName', 'Dutch Open')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q50479069'), ('oName', 'Clash of Continents Exhibition')]
# [('p', 'http://www.wikidata.org/prop/direct/P2670'), ('pName', 'has parts of the class'), ('o', 'http://www.wikidata.org/entity/Q7700500'), ('oName', 'tennis tour')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('o', 'http://www.wikidata.org/entity/Q132377'), ('oName', 'Davis Cup')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q169947'), ('oName', 'Memphis Open')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q26836193'), ('oName', 'WTA tennis tournament')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q4013974'), ('oName', "Charlottesville Men's Pro Challenger")]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q4045891'), ('oName', 'ENGIE OPEN Biarritz')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q248952'), ('oName', 'Sydney International')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q26863790'), ('oName', 'ATP tennis tournament')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('o', 'http://www.wikidata.org/entity/Q270163'), ('oName', 'tennis at the Summer Olympics')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q106938984'), ('oName', 'Serbia Open')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q19428421'), ('oName', 'Hall of Fame Tennis Championships')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q23018491'), ('oName', 'Bangkok tennis tournament')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q299163'), ('oName', 'Barcelona Open')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q299235'), ('oName', 'Swedish Open')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q299287'), ('oName', 'Aegon Pro-Series Loughborough')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q299506'), ('oName', 'Cologne Open')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q299640'), ('oName', 'Ostrava Open')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q299664'), ('oName', 'Oporto Open')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q299668'), ('oName', 'Prague Open (tennis)')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q299948'), ('oName', 'BP National Championships')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q461834'), ('oName', 'Cincinnati Masters')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q299277'), ('oName', 'Intersport Heilbronn Open')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q431360'), ('oName', 'Miami Open')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q206984'), ('oName', 'Billie Jean King Cup')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q1981381'), ('oName', 'Pekao Szczecin Open')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q526017'), ('oName', 'Lexington Challenger')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q168582'), ('oName', 'World Team Cup')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q557814'), ('oName', 'Kazan Summer Cup')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q769431'), ('oName', 'BH Telecom Indoors')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q264806'), ('oName', 'Brisbane International')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q696794'), ('oName', 'Grand Slam Cup')]
# 100

# %%
# write your queries
# Consider the country for sport property of the tennis player (NO Country of citizenship). 
# Return the countries with at least one player who was ranked 1 in the tennis ranking  (the result set must be a list of country IRI and label).

#finding overall ranking

# Q41520 wimbledon
queryString = """

PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
SELECT DISTINCT  ?p ?pName ?o ?oName 
WHERE {
   # ?o ?p wd:Q26863790 .
   # get the label 
   # ?p sc:name ?pName.
   OPTIONAL { ?o sc:name ?oName }.
}
LIMIT 100

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q13222012'), ('oName', 'Kremlin Cup (men)')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q17485677'), ('oName', 'Washington Open (men)')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q270907'), ('oName', 'ATP Finals')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q16465941'), ('oName', 'ATP Dubai Tennis Championships')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q299406'), ('oName', 'Power Horse Cup')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q1993182'), ('oName', 'Open de la Réunion')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q21055686'), ('oName', 'Columbus Challenger')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q14922727'), ('oName', 'U.S. National Indoor Tennis Championships (men)')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q13360692'), ('oName', 'Sydney International (men)')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q265586'), ('oName', 'ATP Studena Croatia Open')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q15116774'), ('oName', 'Swedish Open (men)')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q299159'), ('oName', 'PTT Thailand Open')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q299176'), ('oName', 'Serbia Open (men)')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q299517'), ('oName', 'ATP Long Island')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q299622'), ('oName', 'Hall of Fame Open')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q13222030'), ('oName', 'ATP Miami')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q299174'), ('oName', 'Swiss Indoors')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q299685'), ('oName', "Queen's Club Championships")]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q300007'), ('oName', 'Erste Bank Open')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q299144'), ('oName', 'Atlanta Open')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q1364943'), ('oName', 'Eastbourne International (men)')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q20008620'), ('oName', 'Nottingham Open (men)')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q7699221'), ('oName', 'Rosmalen Grass Court Championships (men)')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q13427623'), ('oName', 'ATP Scottsdale')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q3844309'), ('oName', 'Manchester Trophy Challenger')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q5764200'), ('oName', 'ATP Challenger La Serena')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q558672'), ('oName', 'ATP Challenger Bergamo')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q299454'), ('oName', 'Gerry Weber Open')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q7505806'), ('oName', 'Brisbane International (men)')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q13427619'), ('oName', 'ATP Cincinnati')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q299220'), ('oName', 'ATP Buenos Aires')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q954772'), ('oName', 'China Open (men)')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q156097'), ('oName', 'Hamburg European Open')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q13360713'), ('oName', 'ATP Rome')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q2632546'), ('oName', 'Indianapolis Tennis Championships')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q299147'), ('oName', 'Heineken Open')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q7787114'), ('oName', 'ATP Indian Wells Masters')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q1230166'), ('oName', 'Paris Masters')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q1633700'), ('oName', 'ATP Athens Open')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q1770729'), ('oName', 'ATP Salzburg Indoors')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q2869380'), ('oName', 'Atlanta WCT')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q299193'), ('oName', 'ATP Bordeaux')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q299475'), ('oName', 'ATP Itaparica')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q299791'), ('oName', 'ATP Sao Paulo')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q300028'), ('oName', 'ATP Osaka')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q3601604'), ('oName', 'ATP Challenger Trophy')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q3602052'), ('oName', 'ATP Saint-Vincent')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q3602172'), ('oName', 'Volvo International')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q5109325'), ('oName', 'Mexican Open (tennis)')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q299560'), ('oName', 'Merano Open')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q299236'), ('oName', 'ATP Buzios')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q1851900'), ('oName', 'Brighton International')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q3601563'), ('oName', 'ATP Challenger Guangzhou')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q3649351'), ('oName', 'Cachantún Cup')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q597452'), ('oName', 'Challenger ATP de Salinas Diario Expreso')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q2632544'), ('oName', 'Hong Kong Open (men)')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q14405758'), ('oName', 'Open Castilla y León')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q25378680'), ('oName', 'ATP Challenger Hua Hin')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q299617'), ('oName', 'BMW Open')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q12012406'), ('oName', 'Canadian Open (men)')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q299491'), ('oName', 'SA Tennis Open (men)')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q18926536'), ('oName', 'City of Onkaparinga ATP Challenger')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q13360724'), ('oName', 'ATP Madrid Open')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q50321276'), ('oName', 'Oracle Challenger Series – Indian Wells (men)')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q26844937'), ('oName', 'Chengdu Open')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q107296532'), ('oName', 'Mallorca Championships')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q13221816'), ('oName', 'Portugal Open (men)')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q3602047'), ('oName', 'ATP Roller Open')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q15149863'), ('oName', 'ATP New Haven')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q15781252'), ('oName', 'ATP Shenzhen Open')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q3886561'), ('oName', 'Oslo Open')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q3665808'), ('oName', 'Challenger ATP Iquique')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q3683622'), ('oName', 'Colorado Tennis Classic')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q64827'), ('oName', 'San Marino CEPU Open')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q299712'), ('oName', 'ATP Zaragoza')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q597169'), ('oName', 'Singapore ATP Challenger')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q558266'), ('oName', 'ATP Challenger Tour Finals')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q299415'), ('oName', 'ATP Florence')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q299678'), ('oName', 'Rio Open (men)')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q3602162'), ('oName', 'ATP Venice')]
# [('p', 'http://www.wikidata.org/prop/direct/P1423'), ('pName', 'template has topic'), ('o', 'http://www.wikidata.org/entity/Q6453914'), ('oName', 'Template:Infobox ATP Tennis Tournament')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q3083746'), ('oName', 'Kunming Open')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q20182662'), ('oName', 'Poprad-Tatry ATP Challenger Tour')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q29962841'), ('oName', 'ATP Lyon Open')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q96418391'), ('oName', 'European Indoor Championships')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q15062154'), ('oName', 'Internationaux de Tennis de Vendée')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q106847234'), ('oName', 'Emilia-Romagna Open')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q48644'), ('oName', 'ATP Montevideo')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q2531614'), ('oName', 'ATP Linz')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q1109657'), ('oName', 'Open Castilla y León')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q19799848'), ('oName', 'Batman Cup')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q22298555'), ('oName', 'ATP Sofia Open')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q65078216'), ('oName', 'Zhuhai Championships')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q3601630'), ('oName', 'ATP China Challenger International')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q47511180'), ('oName', 'Oracle Challenger Series – Newport Beach (men)')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q299197'), ('oName', 'ATP Bolzano')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q299795'), ('oName', 'ATP Tashkent Open')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q299707'), ('oName', 'Sanremo Open')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q1393477'), ('oName', 'Green World ATP Challenger')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q19787652')]
# 100

# %%
# write your queries
# Consider the country for sport property of the tennis player (NO Country of citizenship). 
# Return the countries with at least one player who was ranked 1 in the tennis ranking  (the result set must be a list of country IRI and label).

#finding overall ranking

# Q41520 wimbledon
queryString = """

PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
SELECT DISTINCT  ?p ?pName ?o ?oName 
WHERE {
   wd:Q26863790 ?p ?o .
   # get the label 
   # ?p sc:name ?pName.
   OPTIONAL { ?o sc:name ?oName }.
}
LIMIT 100

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P2094'), ('pName', 'competition class'), ('o', 'http://www.wikidata.org/entity/Q56054951'), ('oName', "men's tennis")]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q13219666'), ('oName', 'tennis tournament')]
# [('p', 'http://www.wikidata.org/prop/direct/P664'), ('pName', 'organizer'), ('o', 'http://www.wikidata.org/entity/Q744089'), ('oName', 'Association of Tennis Professionals')]
# [('p', 'http://www.wikidata.org/prop/direct/P641'), ('pName', 'sport'), ('o', 'http://www.wikidata.org/entity/Q847'), ('oName', 'tennis')]
# [('p', 'http://www.wikidata.org/prop/direct/P1424'), ('pName', "topic's main template"), ('o', 'http://www.wikidata.org/entity/Q6453914'), ('oName', 'Template:Infobox ATP Tennis Tournament')]
# [('p', 'http://www.wikidata.org/prop/direct/P8408'), ('pName', 'KBpedia ID'), ('o', 'ATPTennisTournament')]
# 6

# %%
# write your queries
# Consider the country for sport property of the tennis player (NO Country of citizenship). 
# Return the countries with at least one player who was ranked 1 in the tennis ranking  (the result set must be a list of country IRI and label).

#finding overall ranking

# Q41520 wimbledon
queryString = """

PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
SELECT DISTINCT  ?p ?pName ?o ?oName 
WHERE {
   wd:Q744089 ?p ?o .
   # get the label 
   # ?p sc:name ?pName.
   OPTIONAL { ?o sc:name ?oName }.
}
LIMIT 100

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P159'), ('pName', 'headquarters location'), ('o', 'http://www.wikidata.org/entity/Q84'), ('oName', 'London')]
# [('p', 'http://www.wikidata.org/prop/direct/P641'), ('pName', 'sport'), ('o', 'http://www.wikidata.org/entity/Q847'), ('oName', 'tennis')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('o', 'http://www.wikidata.org/entity/Q4438121'), ('oName', 'sports organization')]
# [('p', 'http://www.wikidata.org/prop/direct/P1424'), ('pName', "topic's main template"), ('o', 'http://www.wikidata.org/entity/Q6452600'), ('oName', 'Template:ATP Tournament')]
# [('p', 'http://www.wikidata.org/prop/direct/P1687'), ('pName', 'Wikidata property'), ('o', 'http://www.wikidata.org/entity/P536'), ('oName', 'ATP player ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1687'), ('pName', 'Wikidata property'), ('o', 'http://www.wikidata.org/entity/P6880'), ('oName', 'ATP tennis tournament edition ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1830'), ('pName', 'owner of'), ('o', 'http://www.wikidata.org/entity/Q14580059'), ('oName', 'ATP website')]
# [('p', 'http://www.wikidata.org/prop/direct/P1889'), ('pName', 'different from'), ('o', 'http://www.wikidata.org/entity/Q186929'), ('oName', 'ATP')]
# [('p', 'http://www.wikidata.org/prop/direct/P1424'), ('pName', "topic's main template"), ('o', 'http://www.wikidata.org/entity/Q5619059'), ('oName', 'Template:ATP')]
# [('p', 'http://www.wikidata.org/prop/direct/P910'), ('pName', "topic's main category"), ('o', 'http://www.wikidata.org/entity/Q8713888'), ('oName', 'Category:Association of Tennis Professionals')]
# [('p', 'http://www.wikidata.org/prop/direct/P1417'), ('pName', 'Encyclopædia Britannica Online ID'), ('o', 'topic/Association-of-Tennis-Professionals')]
# [('p', 'http://www.wikidata.org/prop/direct/P1813'), ('pName', 'short name'), ('o', 'ATP')]
# [('p', 'http://www.wikidata.org/prop/direct/P2002'), ('pName', 'Twitter username'), ('o', 'ATPMedia')]
# [('p', 'http://www.wikidata.org/prop/direct/P2002'), ('pName', 'Twitter username'), ('o', 'TennisTV')]
# [('p', 'http://www.wikidata.org/prop/direct/P213'), ('pName', 'ISNI'), ('o', '0000 0000 9122 7569')]
# [('p', 'http://www.wikidata.org/prop/direct/P214'), ('pName', 'VIAF ID'), ('o', '133461607')]
# [('p', 'http://www.wikidata.org/prop/direct/P244'), ('pName', 'Library of Congress authority ID'), ('o', 'nr94010467')]
# [('p', 'http://www.wikidata.org/prop/direct/P2924'), ('pName', 'Great Russian Encyclopedia Online ID'), ('o', '3455800')]
# [('p', 'http://www.wikidata.org/prop/direct/P646'), ('pName', 'Freebase ID'), ('o', '/m/02y63w')]
# [('p', 'http://www.wikidata.org/prop/direct/P7859'), ('pName', 'WorldCat Identities ID'), ('o', 'lccn-nr94010467')]
# [('p', 'http://www.wikidata.org/prop/direct/P856'), ('pName', 'official website'), ('o', 'https://www.atptour.com')]
# 21

# %%
# write your queries
# Consider the country for sport property of the tennis player (NO Country of citizenship). 
# Return the countries with at least one player who was ranked 1 in the tennis ranking  (the result set must be a list of country IRI and label).

#finding overall ranking

# Q41520 wimbledon

queryString = """

PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
SELECT DISTINCT ?p ?pName ?o ?oName
WHERE {
   wd:Q41520 ?p ?o.
   # get the label 
   OPTIONAL { ?p sc:name ?pName }.
   OPTIONAL { ?o sc:name ?oName }.
}
LIMIT 100

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q736742'), ('oName', 'Wimbledon')]
# [('p', 'http://www.wikidata.org/prop/direct/P1424'), ('pName', "topic's main template"), ('o', 'http://www.wikidata.org/entity/Q43323825'), ('oName', 'Template:Wimbledon player')]
# [('p', 'http://www.wikidata.org/prop/direct/P1687'), ('pName', 'Wikidata property'), ('o', 'http://www.wikidata.org/entity/P4503'), ('oName', 'Wimbledon player ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P17'), ('pName', 'country'), ('o', 'http://www.wikidata.org/entity/Q145'), ('oName', 'United Kingdom')]
# [('p', 'http://www.wikidata.org/prop/direct/P1889'), ('pName', 'different from'), ('o', 'http://www.wikidata.org/entity/Q206375'), ('oName', 'Wimbledon')]
# [('p', 'http://www.wikidata.org/prop/direct/P2354'), ('pName', 'has list'), ('o', 'http://www.wikidata.org/entity/Q6585893'), ('oName', 'list of Wimbledon singles finalists during the open era')]
# [('p', 'http://www.wikidata.org/prop/direct/P276'), ('pName', 'location'), ('o', 'http://www.wikidata.org/entity/Q815369'), ('oName', 'All England Lawn Tennis and Croquet Club')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q13219666'), ('oName', 'tennis tournament')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('o', 'http://www.wikidata.org/entity/Q18608583'), ('oName', 'recurring sporting event')]
# [('p', 'http://www.wikidata.org/prop/direct/P361'), ('pName', 'part of'), ('o', 'http://www.wikidata.org/entity/Q102113'), ('oName', 'Grand Slam of tennis')]
# [('p', 'http://www.wikidata.org/prop/direct/P4622'), ('pName', 'trophy awarded'), ('o', 'http://www.wikidata.org/entity/Q7920608'), ('oName', 'Venus Rosewater Dish')]
# [('p', 'http://www.wikidata.org/prop/direct/P641'), ('pName', 'sport'), ('o', 'http://www.wikidata.org/entity/Q847'), ('oName', 'tennis')]
# [('p', 'http://www.wikidata.org/prop/direct/P664'), ('pName', 'organizer'), ('o', 'http://www.wikidata.org/entity/Q223041'), ('oName', 'International Tennis Federation')]
# [('p', 'http://www.wikidata.org/prop/direct/P664'), ('pName', 'organizer'), ('o', 'http://www.wikidata.org/entity/Q815369'), ('oName', 'All England Lawn Tennis and Croquet Club')]
# [('p', 'http://www.wikidata.org/prop/direct/P664'), ('pName', 'organizer'), ('o', 'http://www.wikidata.org/entity/Q1337913'), ('oName', 'Lawn Tennis Association')]
# [('p', 'http://www.wikidata.org/prop/direct/P765'), ('pName', 'surface played on'), ('o', 'http://www.wikidata.org/entity/Q1151291'), ('oName', 'grass court')]
# [('p', 'http://www.wikidata.org/prop/direct/P7959'), ('pName', 'historic county'), ('o', 'http://www.wikidata.org/entity/Q67443130'), ('oName', 'Surrey')]
# [('p', 'http://www.wikidata.org/prop/direct/P910'), ('pName', "topic's main category"), ('o', 'http://www.wikidata.org/entity/Q5326534'), ('oName', 'Category:The Championships, Wimbledon')]
# [('p', 'http://www.wikidata.org/prop/direct/P1417'), ('pName', 'Encyclopædia Britannica Online ID'), ('o', 'sports/Wimbledon-Championships')]
# [('p', 'http://www.wikidata.org/prop/direct/P18'), ('pName', 'image'), ('o', 'http://commons.wikimedia.org/wiki/Special:FilePath/Wimbledon%20Court%201.jpg')]
# [('p', 'http://www.wikidata.org/prop/direct/P2002'), ('pName', 'Twitter username'), ('o', 'Wimbledon')]
# [('p', 'http://www.wikidata.org/prop/direct/P2003'), ('pName', 'Instagram username'), ('o', 'wimbledon')]
# [('p', 'http://www.wikidata.org/prop/direct/P2013'), ('pName', 'Facebook ID'), ('o', 'wimbledon')]
# [('p', 'http://www.wikidata.org/prop/direct/P214'), ('pName', 'VIAF ID'), ('o', '261278845')]
# [('p', 'http://www.wikidata.org/prop/direct/P2257'), ('pName', 'event interval'), ('o', '1')]
# [('p', 'http://www.wikidata.org/prop/direct/P227'), ('pName', 'GND ID'), ('o', '4191833-2')]
# [('p', 'http://www.wikidata.org/prop/direct/P2397'), ('pName', 'YouTube channel ID'), ('o', 'UCNa8NxMgSm7m4Ii9d4QGk1Q')]
# [('p', 'http://www.wikidata.org/prop/direct/P244'), ('pName', 'Library of Congress authority ID'), ('o', 'n99043286')]
# [('p', 'http://www.wikidata.org/prop/direct/P2924'), ('pName', 'Great Russian Encyclopedia Online ID'), ('o', '4216977')]
# [('p', 'http://www.wikidata.org/prop/direct/P3221'), ('pName', 'New York Times topic ID'), ('o', 'subject/wimbledon')]
# [('p', 'http://www.wikidata.org/prop/direct/P3417'), ('pName', 'Quora topic ID'), ('o', 'Wimbledon-Championships')]
# [('p', 'http://www.wikidata.org/prop/direct/P3479'), ('pName', 'Omni topic ID'), ('o', 'c5ac3ccb-e6b7-4eff-a4f6-e33453b2f60e')]
# [('p', 'http://www.wikidata.org/prop/direct/P373'), ('pName', 'Commons category'), ('o', 'Wimbledon Championships')]
# [('p', 'http://www.wikidata.org/prop/direct/P4431'), ('pName', 'Google Doodle'), ('o', '140th-anniversary-of-wimbledon')]
# [('p', 'http://www.wikidata.org/prop/direct/P571'), ('pName', 'inception'), ('o', '1877-01-01T00:00:00Z')]
# [('p', 'http://www.wikidata.org/prop/direct/P646'), ('pName', 'Freebase ID'), ('o', '/m/0mmmt')]
# [('p', 'http://www.wikidata.org/prop/direct/P691'), ('pName', 'NKCR AUT ID'), ('o', 'kn20120713006')]
# [('p', 'http://www.wikidata.org/prop/direct/P7818'), ('pName', 'French Vikidia ID'), ('o', 'Tournoi_de_Wimbledon')]
# [('p', 'http://www.wikidata.org/prop/direct/P7859'), ('pName', 'WorldCat Identities ID'), ('o', 'lccn-n99043286')]
# [('p', 'http://www.wikidata.org/prop/direct/P856'), ('pName', 'official website'), ('o', 'http://www.wimbledon.com')]
# [('p', 'http://www.wikidata.org/prop/direct/P8687'), ('pName', 'social media followers'), ('o', '788000')]
# [('p', 'http://www.wikidata.org/prop/direct/P8687'), ('pName', 'social media followers'), ('o', '3738654')]
# [('p', 'http://www.wikidata.org/prop/direct/P948'), ('pName', 'page banner'), ('o', 'http://commons.wikimedia.org/wiki/Special:FilePath/Wimbledon%20Banner.jpg')]
# [('p', 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), ('o', 'http://wikiba.se/ontology#Item')]
# [('p', 'http://www.wikidata.org/prop/direct-normalized/P214'), ('o', 'http://viaf.org/viaf/261278845')]
# [('p', 'http://www.wikidata.org/prop/direct-normalized/P227'), ('o', 'https://d-nb.info/gnd/4191833-2')]
# [('p', 'http://www.wikidata.org/prop/direct-normalized/P244'), ('o', 'https://id.loc.gov/authorities/names/n99043286')]
# [('p', 'http://www.wikidata.org/prop/direct-normalized/P646'), ('o', 'http://g.co/kg/m/0mmmt')]
# [('p', 'http://schema.org/name'), ('o', 'Wimbledon Championships')]
# 49

# %%
# write your queries
# Consider the country for sport property of the tennis player (NO Country of citizenship). 
# Return the countries with at least one player who was ranked 1 in the tennis ranking  (the result set must be a list of country IRI and label).

#finding overall ranking

# Q41520 wimbledon

queryString = """

PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
SELECT DISTINCT ?p ?pName ?o ?oName
WHERE {
   wd:Q223041 ?p ?o.
   # get the label 
   OPTIONAL { ?p sc:name ?pName }.
   OPTIONAL { ?o sc:name ?oName }.
}
LIMIT 100

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P1424'), ('pName', "topic's main template"), ('o', 'http://www.wikidata.org/entity/Q13233631'), ('oName', 'Template:ITF profile')]
# [('p', 'http://www.wikidata.org/prop/direct/P159'), ('pName', 'headquarters location'), ('o', 'http://www.wikidata.org/entity/Q84'), ('oName', 'London')]
# [('p', 'http://www.wikidata.org/prop/direct/P1687'), ('pName', 'Wikidata property'), ('o', 'http://www.wikidata.org/entity/P599'), ('oName', 'ITF player ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1687'), ('pName', 'Wikidata property'), ('o', 'http://www.wikidata.org/entity/P4299'), ('oName', 'ITF wheelchair player ID until 2019')]
# [('p', 'http://www.wikidata.org/prop/direct/P1687'), ('pName', 'Wikidata property'), ('o', 'http://www.wikidata.org/entity/P6841'), ('oName', 'ITF tournament ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1687'), ('pName', 'Wikidata property'), ('o', 'http://www.wikidata.org/entity/P8618'), ('oName', 'ITF player ID 2020')]
# [('p', 'http://www.wikidata.org/prop/direct/P1830'), ('pName', 'owner of'), ('o', 'http://www.wikidata.org/entity/Q14580049'), ('oName', 'ITF website')]
# [('p', 'http://www.wikidata.org/prop/direct/P1830'), ('pName', 'owner of'), ('o', 'http://www.wikidata.org/entity/Q56617835'), ('oName', 'FedCup website')]
# [('p', 'http://www.wikidata.org/prop/direct/P2541'), ('pName', 'operating area'), ('o', 'http://www.wikidata.org/entity/Q2'), ('oName', 'Earth')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('o', 'http://www.wikidata.org/entity/Q98426739'), ('oName', 'tennis association')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('o', 'http://www.wikidata.org/entity/Q11422536'), ('oName', 'international sport governing body')]
# [('p', 'http://www.wikidata.org/prop/direct/P463'), ('pName', 'member of'), ('o', 'http://www.wikidata.org/entity/Q1067053'), ('oName', 'Global Association of International Sports Federations')]
# [('p', 'http://www.wikidata.org/prop/direct/P463'), ('pName', 'member of'), ('o', 'http://www.wikidata.org/entity/Q2420112'), ('oName', 'Association of Summer Olympic International Federations')]
# [('p', 'http://www.wikidata.org/prop/direct/P6365'), ('pName', 'member category'), ('o', 'http://www.wikidata.org/entity/Q8666190'), ('oName', 'Category:National members of the International Tennis Federation')]
# [('p', 'http://www.wikidata.org/prop/direct/P641'), ('pName', 'sport'), ('o', 'http://www.wikidata.org/entity/Q847'), ('oName', 'tennis')]
# [('p', 'http://www.wikidata.org/prop/direct/P910'), ('pName', "topic's main category"), ('o', 'http://www.wikidata.org/entity/Q8550725'), ('oName', 'Category:International Tennis Federation')]
# [('p', 'http://www.wikidata.org/prop/direct/P1417'), ('pName', 'Encyclopædia Britannica Online ID'), ('o', 'topic/International-Tennis-Federation')]
# [('p', 'http://www.wikidata.org/prop/direct/P2002'), ('pName', 'Twitter username'), ('o', 'itf_tennis')]
# [('p', 'http://www.wikidata.org/prop/direct/P2003'), ('pName', 'Instagram username'), ('o', 'itf__tennis')]
# [('p', 'http://www.wikidata.org/prop/direct/P2013'), ('pName', 'Facebook ID'), ('o', 'InternationalTennisFederation')]
# [('p', 'http://www.wikidata.org/prop/direct/P213'), ('pName', 'ISNI'), ('o', '0000 0001 2156 6570')]
# [('p', 'http://www.wikidata.org/prop/direct/P214'), ('pName', 'VIAF ID'), ('o', '129835064')]
# [('p', 'http://www.wikidata.org/prop/direct/P227'), ('pName', 'GND ID'), ('o', '5048394-8')]
# [('p', 'http://www.wikidata.org/prop/direct/P2397'), ('pName', 'YouTube channel ID'), ('o', 'UCsyvlpbK0BTEc3jec6nhPyQ')]
# [('p', 'http://www.wikidata.org/prop/direct/P244'), ('pName', 'Library of Congress authority ID'), ('o', 'n81078023')]
# [('p', 'http://www.wikidata.org/prop/direct/P269'), ('pName', 'IdRef ID'), ('o', '094140553')]
# [('p', 'http://www.wikidata.org/prop/direct/P2924'), ('pName', 'Great Russian Encyclopedia Online ID'), ('o', '2199026')]
# [('p', 'http://www.wikidata.org/prop/direct/P373'), ('pName', 'Commons category'), ('o', 'International Tennis Federation')]
# [('p', 'http://www.wikidata.org/prop/direct/P3762'), ('pName', 'openMLOL author ID'), ('o', '165762')]
# [('p', 'http://www.wikidata.org/prop/direct/P409'), ('pName', 'Libraries Australia ID'), ('o', '36318548')]
# [('p', 'http://www.wikidata.org/prop/direct/P4527'), ('pName', 'UK Parliament thesaurus ID'), ('o', '37808')]
# [('p', 'http://www.wikidata.org/prop/direct/P571'), ('pName', 'inception'), ('o', '1912-03-01T00:00:00Z')]
# [('p', 'http://www.wikidata.org/prop/direct/P6366'), ('pName', 'Microsoft Academic ID'), ('o', '37098086')]
# [('p', 'http://www.wikidata.org/prop/direct/P646'), ('pName', 'Freebase ID'), ('o', '/m/02t8k5')]
# [('p', 'http://www.wikidata.org/prop/direct/P7859'), ('pName', 'WorldCat Identities ID'), ('o', 'lccn-n81078023')]
# [('p', 'http://www.wikidata.org/prop/direct/P856'), ('pName', 'official website'), ('o', 'http://www.itftennis.com/')]
# [('p', 'http://www.wikidata.org/prop/direct/P8687'), ('pName', 'social media followers'), ('o', '42037')]
# [('p', 'http://www.wikidata.org/prop/direct/P906'), ('pName', 'SELIBR ID'), ('o', '378153')]
# [('p', 'http://www.wikidata.org/prop/direct/P950'), ('pName', 'Biblioteca Nacional de España ID'), ('o', 'XX110652')]
# [('p', 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), ('o', 'http://wikiba.se/ontology#Item')]
# [('p', 'http://www.wikidata.org/prop/direct-normalized/P214'), ('o', 'http://viaf.org/viaf/129835064')]
# [('p', 'http://www.wikidata.org/prop/direct-normalized/P227'), ('o', 'https://d-nb.info/gnd/5048394-8')]
# [('p', 'http://www.wikidata.org/prop/direct-normalized/P244'), ('o', 'https://id.loc.gov/authorities/names/n81078023')]
# [('p', 'http://www.wikidata.org/prop/direct-normalized/P269'), ('o', 'http://www.idref.fr/094140553/id')]
# [('p', 'http://www.wikidata.org/prop/direct-normalized/P6366'), ('o', 'http://ma-graph.org/entity/37098086')]
# [('p', 'http://www.wikidata.org/prop/direct-normalized/P646'), ('o', 'http://g.co/kg/m/02t8k5')]
# [('p', 'http://www.wikidata.org/prop/direct-normalized/P906'), ('o', 'http://libris.kb.se/resource/auth/378153')]
# [('p', 'http://www.wikidata.org/prop/direct-normalized/P950'), ('o', 'http://datos.bne.es/resource/XX110652')]
# [('p', 'http://schema.org/name'), ('o', 'International Tennis Federation')]
# 49

# %%
# write your queries
# Consider the country for sport property of the tennis player (NO Country of citizenship). 
# Return the countries with at least one player who was ranked 1 in the tennis ranking  (the result set must be a list of country IRI and label).

#finding overall ranking

# Q41520 wimbledon

queryString = """

PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
SELECT DISTINCT ?p ?pName ?o ?oName
WHERE {
   wd:Q102113 ?p ?o.
   # get the label 
   OPTIONAL { ?p sc:name ?pName }.
   OPTIONAL { ?o sc:name ?oName }.
}
LIMIT 100

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P1424'), ('pName', "topic's main template"), ('o', 'http://www.wikidata.org/entity/Q5851433'), ('oName', 'Template:Infobox GrandSlamTournaments')]
# [('p', 'http://www.wikidata.org/prop/direct/P2354'), ('pName', 'has list'), ('o', 'http://www.wikidata.org/entity/Q645455'), ('oName', "list of Grand Slam women's singles champions")]
# [('p', 'http://www.wikidata.org/prop/direct/P2354'), ('pName', 'has list'), ('o', 'http://www.wikidata.org/entity/Q1426439'), ('oName', "list of Grand Slam men's singles champions")]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q7700500'), ('oName', 'tennis tour')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('o', 'http://www.wikidata.org/entity/Q50301185'), ('oName', 'tennis tour with multiple editions')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('o', 'http://www.wikidata.org/entity/Q123577'), ('oName', 'US Open')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('o', 'http://www.wikidata.org/entity/Q60874'), ('oName', 'Australian Open')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('o', 'http://www.wikidata.org/entity/Q2223649'), ('oName', 'French cheese')]
# [('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('o', 'http://www.wikidata.org/entity/Q41520'), ('oName', 'Wimbledon Championships')]
# [('p', 'http://www.wikidata.org/prop/direct/P641'), ('pName', 'sport'), ('o', 'http://www.wikidata.org/entity/Q847'), ('oName', 'tennis')]
# [('p', 'http://www.wikidata.org/prop/direct/P910'), ('pName', "topic's main category"), ('o', 'http://www.wikidata.org/entity/Q18156144'), ('oName', 'Category:Grand Slam (tennis)')]
# [('p', 'http://www.wikidata.org/prop/direct/P1417'), ('pName', 'Encyclopædia Britannica Online ID'), ('o', 'sports/Grand-Slam-tennis')]
# [('p', 'http://www.wikidata.org/prop/direct/P18'), ('pName', 'image'), ('o', 'http://commons.wikimedia.org/wiki/Special:FilePath/Tennis%20Racket%20and%20Balls.jpg')]
# [('p', 'http://www.wikidata.org/prop/direct/P2924'), ('pName', 'Great Russian Encyclopedia Online ID'), ('o', '1877358')]
# [('p', 'http://www.wikidata.org/prop/direct/P3222'), ('pName', 'NE.se ID'), ('o', 'grand-slam')]
# [('p', 'http://www.wikidata.org/prop/direct/P3417'), ('pName', 'Quora topic ID'), ('o', 'Grand-Slams')]
# [('p', 'http://www.wikidata.org/prop/direct/P373'), ('pName', 'Commons category'), ('o', 'Grand Slam (tennis)')]
# [('p', 'http://www.wikidata.org/prop/direct/P646'), ('pName', 'Freebase ID'), ('o', '/m/01c2c1')]
# [('p', 'http://www.wikidata.org/prop/direct/P8408'), ('pName', 'KBpedia ID'), ('o', 'GrandSlamTennis')]
# [('p', 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), ('o', 'http://wikiba.se/ontology#Item')]
# [('p', 'http://www.wikidata.org/prop/direct-normalized/P646'), ('o', 'http://g.co/kg/m/01c2c1')]
# [('p', 'http://www.wikidata.org/prop/direct-normalized/P8408'), ('o', 'http://kbpedia.org/kko/rc/GrandSlamTennis')]
# [('p', 'http://schema.org/name'), ('o', 'Grand Slam of tennis')]
# 23

# %%
# write your queries
# Consider the country for sport property of the tennis player (NO Country of citizenship). 
# Return the countries with at least one player who was ranked 1 in the tennis ranking  (the result set must be a list of country IRI and label).

#finding overall ranking

# Q41520 wimbledon

queryString = """

PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
SELECT DISTINCT ?p ?pName ?o ?oName
WHERE {
   # ?o ?p wd:Q102113.
   # get the label 
   OPTIONAL { ?p sc:name ?pName }.
   OPTIONAL { ?o sc:name ?oName }.
}
LIMIT 100

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P1423'), ('pName', 'template has topic'), ('o', 'http://www.wikidata.org/entity/Q5851433'), ('oName', 'Template:Infobox GrandSlamTournaments')]
# [('p', 'http://www.wikidata.org/prop/direct/P2522'), ('pName', 'victory'), ('o', 'http://www.wikidata.org/entity/Q105868'), ('oName', 'Gabriela Sabatini')]
# [('p', 'http://www.wikidata.org/prop/direct/P2522'), ('pName', 'victory'), ('o', 'http://www.wikidata.org/entity/Q105838'), ('oName', 'Marion Bartoli')]
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q11300305'), ('oName', 'Grand Slam')]
# [('p', 'http://www.wikidata.org/prop/direct/P301'), ('pName', "category's main topic"), ('o', 'http://www.wikidata.org/entity/Q18156144'), ('oName', 'Category:Grand Slam (tennis)')]
# [('p', 'http://www.wikidata.org/prop/direct/P361'), ('pName', 'part of'), ('o', 'http://www.wikidata.org/entity/Q41520'), ('oName', 'Wimbledon Championships')]
# [('p', 'http://www.wikidata.org/prop/direct/P361'), ('pName', 'part of'), ('o', 'http://www.wikidata.org/entity/Q43605'), ('oName', 'French Open')]
# [('p', 'http://www.wikidata.org/prop/direct/P361'), ('pName', 'part of'), ('o', 'http://www.wikidata.org/entity/Q123577'), ('oName', 'US Open')]
# [('p', 'http://www.wikidata.org/prop/direct/P361'), ('pName', 'part of'), ('o', 'http://www.wikidata.org/entity/Q60874'), ('oName', 'Australian Open')]
# [('p', 'http://www.wikidata.org/prop/direct/P971'), ('pName', 'category combines topics'), ('o', 'http://www.wikidata.org/entity/Q5326520'), ('oName', 'Category:Grand Slam (tennis) tournaments')]
# [('p', 'http://www.wikidata.org/prop/direct/P971'), ('pName', 'category combines topics'), ('o', 'http://www.wikidata.org/entity/Q8498724'), ('oName', 'Category:Grand Slam (tennis) tournaments navigational boxes')]
# [('p', 'http://www.wikidata.org/prop/direct/P971'), ('pName', 'category combines topics'), ('o', 'http://www.wikidata.org/entity/Q60948776')]
# [('p', 'http://www.wikidata.org/prop/direct/P971'), ('pName', 'category combines topics'), ('o', 'http://www.wikidata.org/entity/Q32490077')]
# [('p', 'http://www.wikidata.org/prop/direct/P971'), ('pName', 'category combines topics'), ('o', 'http://www.wikidata.org/entity/Q32476618')]
# [('p', 'http://www.wikidata.org/prop/direct/P971'), ('pName', 'category combines topics'), ('o', 'http://www.wikidata.org/entity/Q32422294')]
# [('p', 'http://www.wikidata.org/prop/direct/P971'), ('pName', 'category combines topics'), ('o', 'http://www.wikidata.org/entity/Q60944982')]
# [('p', 'http://www.wikidata.org/prop/direct/P971'), ('pName', 'category combines topics'), ('o', 'http://www.wikidata.org/entity/Q32468421')]
# [('p', 'http://www.wikidata.org/prop/direct/P971'), ('pName', 'category combines topics'), ('o', 'http://www.wikidata.org/entity/Q32416809')]
# [('p', 'http://www.w3.org/2002/07/owl#sameAs'), ('o', 'http://www.wikidata.org/entity/Q13196355')]
# [('p', 'http://www.w3.org/2002/07/owl#sameAs'), ('o', 'http://www.wikidata.org/entity/Q13033046')]
# [('p', 'http://schema.org/about'), ('o', 'https://www.wikidata.org/wiki/Special:EntityData/Q102113')]
# 21

# %%
# write your queries
# Consider the country for sport property of the tennis player (NO Country of citizenship). 
# Return the countries with at least one player who was ranked 1 in the tennis ranking  (the result set must be a list of country IRI and label).

#finding overall ranking

# Q41520 wimbledon

queryString = """

PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
SELECT DISTINCT ?p ?pName ?o ?oName
WHERE {
   wd:Q11300305 ?p ?o.
   # get the label 
   OPTIONAL { ?p sc:name ?pName }.
   OPTIONAL { ?o sc:name ?oName }.
}
LIMIT 100

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P279'), ('pName', 'subclass of'), ('o', 'http://www.wikidata.org/entity/Q102113'), ('oName', 'Grand Slam of tennis')]
# [('p', 'http://www.wikidata.org/prop/direct/P641'), ('pName', 'sport'), ('o', 'http://www.wikidata.org/entity/Q1153025'), ('oName', 'wheelchair tennis')]
# [('p', 'http://www.wikidata.org/prop/direct/P2671'), ('pName', 'Google Knowledge Graph ID'), ('o', '/g/121xqb7v')]
# [('p', 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), ('o', 'http://wikiba.se/ontology#Item')]
# [('p', 'http://www.wikidata.org/prop/direct-normalized/P2671'), ('o', 'http://g.co/kg/g/121xqb7v')]
# [('p', 'http://schema.org/name'), ('o', 'Grand Slam')]
# 6

# %%
# write your queries
# Consider the country for sport property of the tennis player (NO Country of citizenship). 
# Return the countries with at least one player who was ranked 1 in the tennis ranking  (the result set must be a list of country IRI and label).

#finding overall ranking

# Q41520 wimbledon

queryString = """

PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
SELECT DISTINCT ?p ?pName ?o ?oName
WHERE {
   # ?o ?p wd:Q11300305.
   # get the label 
   OPTIONAL { ?p sc:name ?pName }.
   OPTIONAL { ?o sc:name ?oName }.
}
LIMIT 100

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://schema.org/about'), ('o', 'https://www.wikidata.org/wiki/Special:EntityData/Q11300305')]
# 1

# %% [markdown]
# #### Can't find overlaal ranking, back to solution 1 with prop wdt:P1352 ('ranking')

# %%
# write your queries
# Consider the country for sport property of the tennis player (NO Country of citizenship). 
# Return the countries with at least one player who was ranked 1 in the tennis ranking  (the result set must be a list of country IRI and label).

#finding overall ranking

# Q41520 wimbledon
queryString = """

PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
SELECT DISTINCT  ?p ?pName ?o ?oName 
WHERE {
   wd:Q1426 ?p ?o .
   # get the label 
   # ?p sc:name ?pName.
   OPTIONAL { ?o sc:name ?oName }.
}
LIMIT 100

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P2522'), ('pName', 'victory'), ('o', 'http://www.wikidata.org/entity/Q22956224'), ('oName', "2017 Australian Open – Men's Singles")]
# [('p', 'http://www.wikidata.org/prop/direct/P2522'), ('pName', 'victory'), ('o', 'http://www.wikidata.org/entity/Q612597'), ('oName', '2007 Tennis Masters Cup')]
# [('p', 'http://www.wikidata.org/prop/direct/P3342'), ('pName', 'significant person'), ('o', 'http://www.wikidata.org/entity/Q54584'), ('oName', 'Andy Roddick')]
# [('p', 'http://www.wikidata.org/prop/direct/P166'), ('pName', 'award received'), ('o', 'http://www.wikidata.org/entity/Q56509472'), ('oName', 'honorary doctor of the University of Basel')]
# [('p', 'http://www.wikidata.org/prop/direct/P1344'), ('pName', 'participant in'), ('o', 'http://www.wikidata.org/entity/Q589310'), ('oName', "tennis at the 2000 Summer Olympics – men's singles")]
# [('p', 'http://www.wikidata.org/prop/direct/P6758'), ('pName', 'supported sports team'), ('o', 'http://www.wikidata.org/entity/Q189671'), ('oName', 'FC Basel')]
# [('p', 'http://www.wikidata.org/prop/direct/P2522'), ('pName', 'victory'), ('o', 'http://www.wikidata.org/entity/Q782589'), ('oName', "2010 Australian Open – Men's Singles")]
# [('p', 'http://www.wikidata.org/prop/direct/P2522'), ('pName', 'victory'), ('o', 'http://www.wikidata.org/entity/Q782420'), ('oName', "2006 Australian Open – Men's Singles")]
# [('p', 'http://www.wikidata.org/prop/direct/P166'), ('pName', 'award received'), ('o', 'http://www.wikidata.org/entity/Q1061233'), ('oName', "L'Équipe Champion of Champions")]
# [('p', 'http://www.wikidata.org/prop/direct/P106'), ('pName', 'occupation'), ('o', 'http://www.wikidata.org/entity/Q10833314'), ('oName', 'tennis player')]
# [('p', 'http://www.wikidata.org/prop/direct/P741'), ('pName', 'playing hand'), ('o', 'http://www.wikidata.org/entity/Q14420039'), ('oName', 'one-handed backhand')]
# [('p', 'http://www.wikidata.org/prop/direct/P1412'), ('pName', 'languages spoken, written or signed'), ('o', 'http://www.wikidata.org/entity/Q150'), ('oName', 'French')]
# [('p', 'http://www.wikidata.org/prop/direct/P1343'), ('pName', 'described by source'), ('o', 'http://www.wikidata.org/entity/Q17290934'), ('oName', 'Lentapedia')]
# [('p', 'http://www.wikidata.org/prop/direct/P1412'), ('pName', 'languages spoken, written or signed'), ('o', 'http://www.wikidata.org/entity/Q1860'), ('oName', 'English')]
# [('p', 'http://www.wikidata.org/prop/direct/P103'), ('pName', 'native language'), ('o', 'http://www.wikidata.org/entity/Q188'), ('oName', 'German')]
# [('p', 'http://www.wikidata.org/prop/direct/P1412'), ('pName', 'languages spoken, written or signed'), ('o', 'http://www.wikidata.org/entity/Q188'), ('oName', 'German')]
# [('p', 'http://www.wikidata.org/prop/direct/P39'), ('pName', 'position held'), ('o', 'http://www.wikidata.org/entity/Q19969187'), ('oName', 'UNICEF Goodwill Ambassador')]
# [('p', 'http://www.wikidata.org/prop/direct/P552'), ('pName', 'handedness'), ('o', 'http://www.wikidata.org/entity/Q3039938'), ('oName', 'right-handedness')]
# [('p', 'http://www.wikidata.org/prop/direct/P1532'), ('pName', 'country for sport'), ('o', 'http://www.wikidata.org/entity/Q39'), ('oName', 'Switzerland')]
# [('p', 'http://www.wikidata.org/prop/direct/P27'), ('pName', 'country of citizenship'), ('o', 'http://www.wikidata.org/entity/Q39'), ('oName', 'Switzerland')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('pName', 'instance of'), ('o', 'http://www.wikidata.org/entity/Q5'), ('oName', 'human')]
# [('p', 'http://www.wikidata.org/prop/direct/P21'), ('pName', 'sex or gender'), ('o', 'http://www.wikidata.org/entity/Q6581097'), ('oName', 'male')]
# [('p', 'http://www.wikidata.org/prop/direct/P1343'), ('pName', 'described by source'), ('o', 'http://www.wikidata.org/entity/Q67311526'), ('oName', 'Obalky knih.cz')]
# [('p', 'http://www.wikidata.org/prop/direct/P108'), ('pName', 'employer'), ('o', 'http://www.wikidata.org/entity/Q740308'), ('oName', 'UNICEF')]
# [('p', 'http://www.wikidata.org/prop/direct/P19'), ('pName', 'place of birth'), ('o', 'http://www.wikidata.org/entity/Q78'), ('oName', 'Basel')]
# [('p', 'http://www.wikidata.org/prop/direct/P641'), ('pName', 'sport'), ('o', 'http://www.wikidata.org/entity/Q847'), ('oName', 'tennis')]
# [('p', 'http://www.wikidata.org/prop/direct/P1344'), ('pName', 'participant in'), ('o', 'http://www.wikidata.org/entity/Q8544'), ('oName', '2000 Summer Olympics')]
# [('p', 'http://www.wikidata.org/prop/direct/P1344'), ('pName', 'participant in'), ('o', 'http://www.wikidata.org/entity/Q8558'), ('oName', '2004 Summer Olympics')]
# [('p', 'http://www.wikidata.org/prop/direct/P140'), ('pName', 'religion'), ('o', 'http://www.wikidata.org/entity/Q9592'), ('oName', 'Catholic Church')]
# [('p', 'http://www.wikidata.org/prop/direct/P2522'), ('pName', 'victory'), ('o', 'http://www.wikidata.org/entity/Q300024'), ('oName', '2011 ATP World Tour Finals')]
# [('p', 'http://www.wikidata.org/prop/direct/P2416'), ('pName', 'sports discipline competed in'), ('o', 'http://www.wikidata.org/entity/Q18123880'), ('oName', 'tennis singles')]
# [('p', 'http://www.wikidata.org/prop/direct/P2416'), ('pName', 'sports discipline competed in'), ('o', 'http://www.wikidata.org/entity/Q18123885'), ('oName', 'tennis doubles')]
# [('p', 'http://www.wikidata.org/prop/direct/P735'), ('pName', 'given name'), ('o', 'http://www.wikidata.org/entity/Q4925304'), ('oName', 'Roger')]
# [('p', 'http://www.wikidata.org/prop/direct/P166'), ('pName', 'award received'), ('o', 'http://www.wikidata.org/entity/Q338737'), ('oName', 'Swiss Sports Personality of the Year')]
# [('p', 'http://www.wikidata.org/prop/direct/P166'), ('pName', 'award received'), ('o', 'http://www.wikidata.org/entity/Q3494048'), ('oName', 'BBC Overseas Sports Personality of the Year')]
# [('p', 'http://www.wikidata.org/prop/direct/P1344'), ('pName', 'participant in'), ('o', 'http://www.wikidata.org/entity/Q581788'), ('oName', "tennis at the 2012 Summer Olympics – men's singles")]
# [('p', 'http://www.wikidata.org/prop/direct/P2522'), ('pName', 'victory'), ('o', 'http://www.wikidata.org/entity/Q753300'), ('oName', "2012 Wimbledon Championships – Gentlemen's Singles")]
# [('p', 'http://www.wikidata.org/prop/direct/P1344'), ('pName', 'participant in'), ('o', 'http://www.wikidata.org/entity/Q757054'), ('oName', "tennis at the 2008 Summer Olympics – men's doubles")]
# [('p', 'http://www.wikidata.org/prop/direct/P2522'), ('pName', 'victory'), ('o', 'http://www.wikidata.org/entity/Q757054'), ('oName', "tennis at the 2008 Summer Olympics – men's doubles")]
# [('p', 'http://www.wikidata.org/prop/direct/P2522'), ('pName', 'victory'), ('o', 'http://www.wikidata.org/entity/Q1074654'), ('oName', "2006 Wimbledon Championships – Men's Singles")]
# [('p', 'http://www.wikidata.org/prop/direct/P2522'), ('pName', 'victory'), ('o', 'http://www.wikidata.org/entity/Q384929'), ('oName', "2005 Wimbledon Championships – Men's Singles")]
# [('p', 'http://www.wikidata.org/prop/direct/P551'), ('pName', 'residence'), ('o', 'http://www.wikidata.org/entity/Q70036'), ('oName', 'Bottmingen')]
# [('p', 'http://www.wikidata.org/prop/direct/P2522'), ('pName', 'victory'), ('o', 'http://www.wikidata.org/entity/Q14916861'), ('oName', '2014 Davis Cup')]
# [('p', 'http://www.wikidata.org/prop/direct/P741'), ('pName', 'playing hand'), ('o', 'http://www.wikidata.org/entity/Q14419931'), ('oName', 'one-handed forehand')]
# [('p', 'http://www.wikidata.org/prop/direct/P2522'), ('pName', 'victory'), ('o', 'http://www.wikidata.org/entity/Q46993124'), ('oName', "2018 Australian Open – Men's Singles")]
# [('p', 'http://www.wikidata.org/prop/direct/P166'), ('pName', 'award received'), ('o', 'http://www.wikidata.org/entity/Q4896696'), ('oName', 'Best International Athlete ESPY Award')]
# [('p', 'http://www.wikidata.org/prop/direct/P286'), ('pName', 'head coach'), ('o', 'http://www.wikidata.org/entity/Q15649219'), ('oName', 'Severin Lüthi')]
# [('p', 'http://www.wikidata.org/prop/direct/P734'), ('pName', 'family name'), ('o', 'http://www.wikidata.org/entity/Q16869916'), ('oName', 'Federer')]
# [('p', 'http://www.wikidata.org/prop/direct/P286'), ('pName', 'head coach'), ('o', 'http://www.wikidata.org/entity/Q261095'), ('oName', 'Ivan Ljubičić')]
# [('p', 'http://www.wikidata.org/prop/direct/P2522'), ('pName', 'victory'), ('o', 'http://www.wikidata.org/entity/Q964291'), ('oName', '2006 Tennis Masters Cup')]
# [('p', 'http://www.wikidata.org/prop/direct/P2522'), ('pName', 'victory'), ('o', 'http://www.wikidata.org/entity/Q300022'), ('oName', '2010 ATP World Tour Finals')]
# [('p', 'http://www.wikidata.org/prop/direct/P2522'), ('pName', 'victory'), ('o', 'http://www.wikidata.org/entity/Q1048953'), ('oName', "2004 US Open – Men's Singles")]
# [('p', 'http://www.wikidata.org/prop/direct/P2522'), ('pName', 'victory'), ('o', 'http://www.wikidata.org/entity/Q731509'), ('oName', "2005 US Open – Men's Singles")]
# [('p', 'http://www.wikidata.org/prop/direct/P2522'), ('pName', 'victory'), ('o', 'http://www.wikidata.org/entity/Q741573'), ('oName', "2009 French Open – Men's Singles")]
# [('p', 'http://www.wikidata.org/prop/direct/P2522'), ('pName', 'victory'), ('o', 'http://www.wikidata.org/entity/Q912506'), ('oName', "2006 US Open – Men's Singles")]
# [('p', 'http://www.wikidata.org/prop/direct/P2522'), ('pName', 'victory'), ('o', 'http://www.wikidata.org/entity/Q248965'), ('oName', "2004 Wimbledon Championships – Men's Singles")]
# [('p', 'http://www.wikidata.org/prop/direct/P2522'), ('pName', 'victory'), ('o', 'http://www.wikidata.org/entity/Q378627'), ('oName', "2003 Wimbledon Championships – Men's Singles")]
# [('p', 'http://www.wikidata.org/prop/direct/P286'), ('pName', 'head coach'), ('o', 'http://www.wikidata.org/entity/Q1348847'), ('oName', 'José Higueras')]
# [('p', 'http://www.wikidata.org/prop/direct/P2522'), ('pName', 'victory'), ('o', 'http://www.wikidata.org/entity/Q779654'), ('oName', "2004 Australian Open - men's singles")]
# [('p', 'http://www.wikidata.org/prop/direct/P2522'), ('pName', 'victory'), ('o', 'http://www.wikidata.org/entity/Q25344123'), ('oName', "2017 Wimbledon Championships – Men's Singles")]
# [('p', 'http://www.wikidata.org/prop/direct/P22'), ('pName', 'father'), ('o', 'http://www.wikidata.org/entity/Q17291275'), ('oName', 'Robert Federer')]
# [('p', 'http://www.wikidata.org/prop/direct/P25'), ('pName', 'mother'), ('o', 'http://www.wikidata.org/entity/Q17291278'), ('oName', 'Lynette Federer')]
# [('p', 'http://www.wikidata.org/prop/direct/P3373'), ('pName', 'sibling'), ('o', 'http://www.wikidata.org/entity/Q17291284'), ('oName', 'Dziana Federer')]
# [('p', 'http://www.wikidata.org/prop/direct/P40'), ('pName', 'child'), ('o', 'http://www.wikidata.org/entity/Q17291294'), ('oName', 'Myla Federer')]
# [('p', 'http://www.wikidata.org/prop/direct/P40'), ('pName', 'child'), ('o', 'http://www.wikidata.org/entity/Q17291300'), ('oName', 'Charlene Federer')]
# [('p', 'http://www.wikidata.org/prop/direct/P40'), ('pName', 'child'), ('o', 'http://www.wikidata.org/entity/Q17291308'), ('oName', 'Leo Federer')]
# [('p', 'http://www.wikidata.org/prop/direct/P40'), ('pName', 'child'), ('o', 'http://www.wikidata.org/entity/Q17291316'), ('oName', 'Lennart Federer')]
# [('p', 'http://www.wikidata.org/prop/direct/P26'), ('pName', 'spouse'), ('o', 'http://www.wikidata.org/entity/Q233306'), ('oName', 'Mirka Federer')]
# [('p', 'http://www.wikidata.org/prop/direct/P2522'), ('pName', 'victory'), ('o', 'http://www.wikidata.org/entity/Q2478340'), ('oName', '2011 BNP Paribas Masters – singles')]
# [('p', 'http://www.wikidata.org/prop/direct/P2522'), ('pName', 'victory'), ('o', 'http://www.wikidata.org/entity/Q751798'), ('oName', "2009 Wimbledon Championships – Men's Singles")]
# [('p', 'http://www.wikidata.org/prop/direct/P166'), ('pName', 'award received'), ('o', 'http://www.wikidata.org/entity/Q693708'), ('oName', 'ITF World Champions')]
# [('p', 'http://www.wikidata.org/prop/direct/P2522'), ('pName', 'victory'), ('o', 'http://www.wikidata.org/entity/Q782451'), ('oName', "2007 Australian Open – Men's Singles")]
# [('p', 'http://www.wikidata.org/prop/direct/P2522'), ('pName', 'victory'), ('o', 'http://www.wikidata.org/entity/Q912483'), ('oName', "2007 Wimbledon Championships – Men's Singles")]
# [('p', 'http://www.wikidata.org/prop/direct/P2522'), ('pName', 'victory'), ('o', 'http://www.wikidata.org/entity/Q304072'), ('oName', "2008 US Open – Men's Singles")]
# [('p', 'http://www.wikidata.org/prop/direct/P2522'), ('pName', 'victory'), ('o', 'http://www.wikidata.org/entity/Q2031910'), ('oName', '2003 Tennis Masters Cup')]
# [('p', 'http://www.wikidata.org/prop/direct/P2522'), ('pName', 'victory'), ('o', 'http://www.wikidata.org/entity/Q2094307'), ('oName', '2004 Tennis Masters Cup')]
# [('p', 'http://www.wikidata.org/prop/direct/P2522'), ('pName', 'victory'), ('o', 'http://www.wikidata.org/entity/Q836815'), ('oName', "2007 US Open – Men's Singles")]
# [('p', 'http://www.wikidata.org/prop/direct/P910'), ('pName', "topic's main category"), ('o', 'http://www.wikidata.org/entity/Q7257144'), ('oName', 'Category:Roger Federer')]
# [('p', 'http://www.wikidata.org/prop/direct/P286'), ('pName', 'head coach'), ('o', 'http://www.wikidata.org/entity/Q1968483'), ('oName', 'Peter Carter')]
# [('p', 'http://www.wikidata.org/prop/direct/P463'), ('pName', 'member of'), ('o', 'http://www.wikidata.org/entity/Q1675504'), ('oName', 'Swiss Tennis')]
# [('p', 'http://www.wikidata.org/prop/direct/P1006'), ('pName', 'Nationale Thesaurus voor Auteurs ID'), ('o', '345755332')]
# [('p', 'http://www.wikidata.org/prop/direct/P1263'), ('pName', 'NNDB people ID'), ('o', '963/000047822')]
# [('p', 'http://www.wikidata.org/prop/direct/P1280'), ('pName', 'CONOR.SI ID'), ('o', '196081763')]
# [('p', 'http://www.wikidata.org/prop/direct/P1284'), ('pName', 'Munzinger person ID'), ('o', '01000005836')]
# [('p', 'http://www.wikidata.org/prop/direct/P1285'), ('pName', 'Munzinger Sport number'), ('o', '01000005836')]
# [('p', 'http://www.wikidata.org/prop/direct/P1296'), ('pName', 'Gran Enciclopèdia Catalana ID'), ('o', '0278173')]
# [('p', 'http://www.wikidata.org/prop/direct/P1352'), ('pName', 'ranking'), ('o', '1')]
# [('p', 'http://www.wikidata.org/prop/direct/P1352'), ('pName', 'ranking'), ('o', '24')]
# [('p', 'http://www.wikidata.org/prop/direct/P1417'), ('pName', 'Encyclopædia Britannica Online ID'), ('o', 'biography/Roger-Federer')]
# [('p', 'http://www.wikidata.org/prop/direct/P1447'), ('pName', 'Sports-Reference.com Olympic athlete ID'), ('o', 'fe/roger-federer-1')]
# [('p', 'http://www.wikidata.org/prop/direct/P1695'), ('pName', 'NLP ID (unique)'), ('o', 'A27741333')]
# [('p', 'http://www.wikidata.org/prop/direct/P1741'), ('pName', 'GTAA ID'), ('o', '98440')]
# [('p', 'http://www.wikidata.org/prop/direct/P18'), ('pName', 'image'), ('o', 'http://commons.wikimedia.org/wiki/Special:FilePath/Roger%20Federer%20%2818405413060%29.jpg')]
# [('p', 'http://www.wikidata.org/prop/direct/P18'), ('pName', 'image'), ('o', 'http://commons.wikimedia.org/wiki/Special:FilePath/R%20federer.jpg')]
# [('p', 'http://www.wikidata.org/prop/direct/P2002'), ('pName', 'Twitter username'), ('o', 'rogerfederer')]
# [('p', 'http://www.wikidata.org/prop/direct/P2003'), ('pName', 'Instagram username'), ('o', 'rogerfederer')]
# [('p', 'http://www.wikidata.org/prop/direct/P2013'), ('pName', 'Facebook ID'), ('o', 'Federer')]
# [('p', 'http://www.wikidata.org/prop/direct/P2019'), ('pName', 'AllMovie person ID'), ('o', 'p445975')]
# [('p', 'http://www.wikidata.org/prop/direct/P2031'), ('pName', 'work period (start)'), ('o', '1998-01-01T00:00:00Z')]
# [('p', 'http://www.wikidata.org/prop/direct/P2048'), ('pName', 'height'), ('o', '185')]
# 100

# %%
# write your queries
# Consider the country for sport property of the tennis player (NO Country of citizenship). 
# Return the countries with at least one player who was ranked 1 in the tennis ranking  (the result set must be a list of country IRI and label).

# Q41520 wimbledon

# P106('occupation'),
# Q10833314 ('tennis player')

# GETTING ALL TENNIS PLAYER
queryString = """

PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
SELECT DISTINCT ?o ?oName 
WHERE {
   # ?o wdt:P106 wd:Q10833314 .
   # get the label 
   OPTIONAL { ?o sc:name ?oName }.
}
LIMIT 100

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('o', 'http://www.wikidata.org/entity/Q1683632'), ('oName', 'Jaroslav Navrátil')]
# [('o', 'http://www.wikidata.org/entity/Q138094'), ('oName', 'Anna Karolína Schmiedlová')]
# [('o', 'http://www.wikidata.org/entity/Q15197746'), ('oName', 'Wesley Koolhof')]
# [('o', 'http://www.wikidata.org/entity/Q1558013'), ('oName', 'Pierre Barthès')]
# [('o', 'http://www.wikidata.org/entity/Q15849678'), ('oName', 'Sue Partridge')]
# [('o', 'http://www.wikidata.org/entity/Q15880574'), ('oName', 'Paul Oosterbaan')]
# [('o', 'http://www.wikidata.org/entity/Q240837'), ('oName', 'Rika Fujiwara')]
# [('o', 'http://www.wikidata.org/entity/Q4134097'), ('oName', 'Margarita Gasparyan')]
# [('o', 'http://www.wikidata.org/entity/Q589611'), ('oName', 'Philippe Chatrier')]
# [('o', 'http://www.wikidata.org/entity/Q16009513'), ('oName', 'James Bayley')]
# [('o', 'http://www.wikidata.org/entity/Q16023406'), ('oName', 'Samuel T. Chase')]
# [('o', 'http://www.wikidata.org/entity/Q16063202'), ('oName', 'Agnete Goldschmidt')]
# [('o', 'http://www.wikidata.org/entity/Q16065254'), ('oName', 'Thorkil Hillerup')]
# [('o', 'http://www.wikidata.org/entity/Q16067006'), ('oName', 'Lois Moyes Bickle')]
# [('o', 'http://www.wikidata.org/entity/Q1660141'), ('oName', 'Perry Jones')]
# [('o', 'http://www.wikidata.org/entity/Q299959'), ('oName', 'Eileen Bennett Whittingstall')]
# [('o', 'http://www.wikidata.org/entity/Q16203224'), ('oName', 'Frederick Campbell Colston')]
# [('o', 'http://www.wikidata.org/entity/Q16204467'), ('oName', 'Andrew Drew')]
# [('o', 'http://www.wikidata.org/entity/Q16208155'), ('oName', 'Chris Forney')]
# [('o', 'http://www.wikidata.org/entity/Q16210951'), ('oName', 'N. M. Smith')]
# [('o', 'http://www.wikidata.org/entity/Q16219279'), ('oName', 'William S. Bond')]
# [('o', 'http://www.wikidata.org/entity/Q16219370'), ('oName', 'John Strachan')]
# [('o', 'http://www.wikidata.org/entity/Q16224596'), ('oName', 'David Kabiller')]
# [('o', 'http://www.wikidata.org/entity/Q16224618'), ('oName', 'Janet Lagasse')]
# [('o', 'http://www.wikidata.org/entity/Q16224631'), ('oName', 'Lee So-ra')]
# [('o', 'http://www.wikidata.org/entity/Q459223'), ('oName', 'Paul Lebreton')]
# [('o', 'http://www.wikidata.org/entity/Q7281705'), ('oName', 'Radu Albot')]
# [('o', 'http://www.wikidata.org/entity/Q17189986'), ('oName', 'Will Coghlan')]
# [('o', 'http://www.wikidata.org/entity/Q18918709'), ('oName', 'Markéta Vondroušová')]
# [('o', 'http://www.wikidata.org/entity/Q6408932'), ('oName', 'Kim Jones')]
# [('o', 'http://www.wikidata.org/entity/Q7176198'), ('oName', 'Peter Oatey')]
# [('o', 'http://www.wikidata.org/entity/Q17291218'), ('oName', 'Djordje Djokovic')]
# [('o', 'http://www.wikidata.org/entity/Q17302035'), ('oName', 'Mary Hamm')]
# [('o', 'http://www.wikidata.org/entity/Q17303008'), ('oName', 'Petra Hradecká')]
# [('o', 'http://www.wikidata.org/entity/Q17323657'), ('oName', 'Sviatlana Pirazhenka')]
# [('o', 'http://www.wikidata.org/entity/Q17327545'), ('oName', 'Marcelo Zormann')]
# [('o', 'http://www.wikidata.org/entity/Q17525743'), ('oName', 'Sanaz Marand')]
# [('o', 'http://www.wikidata.org/entity/Q193661'), ('oName', 'Stan Wawrinka')]
# [('o', 'http://www.wikidata.org/entity/Q3597288'), ('oName', 'Marko Djokovic')]
# [('o', 'http://www.wikidata.org/entity/Q76338'), ('oName', 'Sabine Lisicki')]
# [('o', 'http://www.wikidata.org/entity/Q966542'), ('oName', 'Roberto Bautista Agut')]
# [('o', 'http://www.wikidata.org/entity/Q12768184'), ('oName', 'Jozef Kovalík')]
# [('o', 'http://www.wikidata.org/entity/Q17442289'), ('oName', 'David Sherbeck')]
# [('o', 'http://www.wikidata.org/entity/Q237146'), ('oName', 'Lara Arruabarrena')]
# [('o', 'http://www.wikidata.org/entity/Q15693148'), ('oName', 'Lo Man Wai')]
# [('o', 'http://www.wikidata.org/entity/Q17612829'), ('oName', 'Hunter Reese')]
# [('o', 'http://www.wikidata.org/entity/Q17626628'), ('oName', 'Ernesto Escobedo')]
# [('o', 'http://www.wikidata.org/entity/Q53410'), ('oName', 'John Doeg')]
# [('o', 'http://www.wikidata.org/entity/Q54546'), ('oName', 'Nancy Richey')]
# [('o', 'http://www.wikidata.org/entity/Q4169985'), ('oName', 'Bermet Duvanaeva')]
# [('o', 'http://www.wikidata.org/entity/Q18085277'), ('oName', 'Armistead Neely')]
# [('o', 'http://www.wikidata.org/entity/Q18091446'), ('oName', 'Hank Irvine')]
# [('o', 'http://www.wikidata.org/entity/Q18113506'), ('oName', 'Robin Blakelock')]
# [('o', 'http://www.wikidata.org/entity/Q18129396'), ('oName', 'Gao Xin')]
# [('o', 'http://www.wikidata.org/entity/Q19406'), ('oName', 'David Goffin')]
# [('o', 'http://www.wikidata.org/entity/Q26799554'), ('oName', 'Jeffrey John Wolf')]
# [('o', 'http://www.wikidata.org/entity/Q355333'), ('oName', 'Marcin Matkowski')]
# [('o', 'http://www.wikidata.org/entity/Q4800760'), ('oName', 'Wang Qiang')]
# [('o', 'http://www.wikidata.org/entity/Q1260231'), ('oName', 'Geoff Masters')]
# [('o', 'http://www.wikidata.org/entity/Q17364412'), ('oName', 'Maximilian Marterer')]
# [('o', 'http://www.wikidata.org/entity/Q19330576'), ('oName', 'Darren Walsh')]
# [('o', 'http://www.wikidata.org/entity/Q5880437'), ('oName', 'Gisela Riera')]
# [('o', 'http://www.wikidata.org/entity/Q6376017'), ('oName', 'Kateřina Böhmová')]
# [('o', 'http://www.wikidata.org/entity/Q72091'), ('oName', 'Martin Sinner')]
# [('o', 'http://www.wikidata.org/entity/Q14905846'), ('oName', 'Borna Ćorić')]
# [('o', 'http://www.wikidata.org/entity/Q207352'), ('oName', 'Agnieszka Radwańska')]
# [('o', 'http://www.wikidata.org/entity/Q20968624'), ('oName', 'Viktória Kužmová')]
# [('o', 'http://www.wikidata.org/entity/Q20982979'), ('oName', 'Miyu Kato')]
# [('o', 'http://www.wikidata.org/entity/Q20983768'), ('oName', 'Kerstin Peckl')]
# [('o', 'http://www.wikidata.org/entity/Q21001023'), ('oName', 'Facundo Mena')]
# [('o', 'http://www.wikidata.org/entity/Q21622155'), ('oName', 'Richard Muzaev')]
# [('o', 'http://www.wikidata.org/entity/Q21622265'), ('oName', 'Akiko Ōmae')]
# [('o', 'http://www.wikidata.org/entity/Q21970595'), ('oName', 'Eléonora Molinaro')]
# [('o', 'http://www.wikidata.org/entity/Q312343'), ('oName', 'Milos Raonic')]
# [('o', 'http://www.wikidata.org/entity/Q22022537'), ('oName', 'Martin Zander')]
# [('o', 'http://www.wikidata.org/entity/Q22086227'), ('oName', 'Ellen Perez')]
# [('o', 'http://www.wikidata.org/entity/Q22087891'), ('oName', 'Alexandra Chong')]
# [('o', 'http://www.wikidata.org/entity/Q22958938'), ('oName', 'Alex de Minaur')]
# [('o', 'http://www.wikidata.org/entity/Q22959065'), ('oName', 'Blake Ellis')]
# [('o', 'http://www.wikidata.org/entity/Q21032187'), ('oName', 'Melanie Molitorová')]
# [('o', 'http://www.wikidata.org/entity/Q22911321'), ('oName', 'Eugeniusz Czerepaniak')]
# [('o', 'http://www.wikidata.org/entity/Q22953456'), ('oName', 'Agnese Gustmane')]
# [('o', 'http://www.wikidata.org/entity/Q22957659'), ('oName', 'Jane Régny')]
# [('o', 'http://www.wikidata.org/entity/Q22959202'), ('oName', 'Alvin Gardiner')]
# [('o', 'http://www.wikidata.org/entity/Q22961763'), ('oName', 'Nurin Nabilah Roslan')]
# [('o', 'http://www.wikidata.org/entity/Q22964651'), ('oName', 'Antoni Juanico i Torres')]
# [('o', 'http://www.wikidata.org/entity/Q22965148'), ('oName', 'Francesc Sindreu i Pons')]
# [('o', 'http://www.wikidata.org/entity/Q3051240'), ('oName', 'Elizabeth Little')]
# [('o', 'http://www.wikidata.org/entity/Q2139295'), ('oName', 'Alain Gerbault')]
# [('o', 'http://www.wikidata.org/entity/Q24203552'), ('oName', 'Alexander Kaye Butterworth')]
# [('o', 'http://www.wikidata.org/entity/Q26207574'), ('oName', 'Doaa el-Ghobashy')]
# [('o', 'http://www.wikidata.org/entity/Q26209630'), ('oName', 'Zhu Aiwen')]
# [('o', 'http://www.wikidata.org/entity/Q26210785'), ('oName', 'Kaden Hensel')]
# [('o', 'http://www.wikidata.org/entity/Q26269760'), ('oName', 'Giorgia Marchetti')]
# [('o', 'http://www.wikidata.org/entity/Q27032196'), ('oName', 'Polina Merenkova')]
# [('o', 'http://www.wikidata.org/entity/Q27049237'), ('oName', 'Ljubomir Čelebić')]
# [('o', 'http://www.wikidata.org/entity/Q27057687'), ('oName', 'Gülberk Gültekin')]
# [('o', 'http://www.wikidata.org/entity/Q27244469'), ('oName', 'Agustina Lepore')]
# [('o', 'http://www.wikidata.org/entity/Q27495841'), ('oName', 'Yamile Fors Guerra')]
# [('o', 'http://www.wikidata.org/entity/Q7454263'), ('oName', 'Sergio Galdós')]
# 100

# %%
# write your queries
# Consider the country for sport property of the tennis player (NO Country of citizenship). 
# Return the countries with at least one player who was ranked 1 in the tennis ranking  (the result set must be a list of country IRI and label).

# Q41520 wimbledon

# P106('occupation'),
# Q10833314 ('tennis player')
# --P1352 ('ranking')--> ('o', '1')

# GETTING ALL TENNIS PLAYER
# -> GETTING their ranking

queryString = """

PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
SELECT DISTINCT ?o ?oName ?ranking
WHERE {
   # ?o wdt:P106 wd:Q10833314;
        wdt:P1352 ?ranking
   # get the label 
   OPTIONAL { ?o sc:name ?oName }.
}
LIMIT 100

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('o', 'http://www.wikidata.org/entity/Q138094'), ('oName', 'Anna Karolína Schmiedlová'), ('ranking', '26')]
# [('o', 'http://www.wikidata.org/entity/Q15197746'), ('oName', 'Wesley Koolhof'), ('ranking', '5')]
# [('o', 'http://www.wikidata.org/entity/Q15197746'), ('oName', 'Wesley Koolhof'), ('ranking', '462')]
# [('o', 'http://www.wikidata.org/entity/Q240837'), ('oName', 'Rika Fujiwara'), ('ranking', '13')]
# [('o', 'http://www.wikidata.org/entity/Q240837'), ('oName', 'Rika Fujiwara'), ('ranking', '84')]
# [('o', 'http://www.wikidata.org/entity/Q4134097'), ('oName', 'Margarita Gasparyan'), ('ranking', '25')]
# [('o', 'http://www.wikidata.org/entity/Q7281705'), ('oName', 'Radu Albot'), ('ranking', '56')]
# [('o', 'http://www.wikidata.org/entity/Q7281705'), ('oName', 'Radu Albot'), ('ranking', '108')]
# [('o', 'http://www.wikidata.org/entity/Q18918709'), ('oName', 'Markéta Vondroušová'), ('ranking', '14')]
# [('o', 'http://www.wikidata.org/entity/Q6408932'), ('oName', 'Kim Jones'), ('ranking', '25')]
# [('o', 'http://www.wikidata.org/entity/Q17323657'), ('oName', 'Sviatlana Pirazhenka'), ('ranking', '371')]
# [('o', 'http://www.wikidata.org/entity/Q193661'), ('oName', 'Stan Wawrinka'), ('ranking', '3')]
# [('o', 'http://www.wikidata.org/entity/Q193661'), ('oName', 'Stan Wawrinka'), ('ranking', '19')]
# [('o', 'http://www.wikidata.org/entity/Q193661'), ('oName', 'Stan Wawrinka'), ('ranking', '88')]
# [('o', 'http://www.wikidata.org/entity/Q193661'), ('oName', 'Stan Wawrinka'), ('ranking', '287')]
# [('o', 'http://www.wikidata.org/entity/Q76338'), ('oName', 'Sabine Lisicki'), ('ranking', '12')]
# [('o', 'http://www.wikidata.org/entity/Q76338'), ('oName', 'Sabine Lisicki'), ('ranking', '35')]
# [('o', 'http://www.wikidata.org/entity/Q76338'), ('oName', 'Sabine Lisicki'), ('ranking', '92')]
# [('o', 'http://www.wikidata.org/entity/Q966542'), ('oName', 'Roberto Bautista Agut'), ('ranking', '17')]
# [('o', 'http://www.wikidata.org/entity/Q966542'), ('oName', 'Roberto Bautista Agut'), ('ranking', '169')]
# [('o', 'http://www.wikidata.org/entity/Q237146'), ('oName', 'Lara Arruabarrena'), ('ranking', '28')]
# [('o', 'http://www.wikidata.org/entity/Q19406'), ('oName', 'David Goffin'), ('ranking', '19')]
# [('o', 'http://www.wikidata.org/entity/Q19406'), ('oName', 'David Goffin'), ('ranking', '158')]
# [('o', 'http://www.wikidata.org/entity/Q355333'), ('oName', 'Marcin Matkowski'), ('ranking', '7')]
# [('o', 'http://www.wikidata.org/entity/Q355333'), ('oName', 'Marcin Matkowski'), ('ranking', '647')]
# [('o', 'http://www.wikidata.org/entity/Q4800760'), ('oName', 'Wang Qiang'), ('ranking', '12')]
# [('o', 'http://www.wikidata.org/entity/Q6376017'), ('oName', 'Kateřina Böhmová'), ('ranking', '107')]
# [('o', 'http://www.wikidata.org/entity/Q6376017'), ('oName', 'Kateřina Böhmová'), ('ranking', '214')]
# [('o', 'http://www.wikidata.org/entity/Q14905846'), ('oName', 'Borna Ćorić'), ('ranking', '35')]
# [('o', 'http://www.wikidata.org/entity/Q14905846'), ('oName', 'Borna Ćorić'), ('ranking', '413')]
# [('o', 'http://www.wikidata.org/entity/Q207352'), ('oName', 'Agnieszka Radwańska'), ('ranking', '1')]
# [('o', 'http://www.wikidata.org/entity/Q207352'), ('oName', 'Agnieszka Radwańska'), ('ranking', '2')]
# [('o', 'http://www.wikidata.org/entity/Q207352'), ('oName', 'Agnieszka Radwańska'), ('ranking', '16')]
# [('o', 'http://www.wikidata.org/entity/Q20968624'), ('oName', 'Viktória Kužmová'), ('ranking', '24')]
# [('o', 'http://www.wikidata.org/entity/Q20968624'), ('oName', 'Viktória Kužmová'), ('ranking', '27')]
# [('o', 'http://www.wikidata.org/entity/Q20968624'), ('oName', 'Viktória Kužmová'), ('ranking', '43')]
# [('o', 'http://www.wikidata.org/entity/Q20982979'), ('oName', 'Miyu Kato'), ('ranking', '30')]
# [('o', 'http://www.wikidata.org/entity/Q21622265'), ('oName', 'Akiko Ōmae'), ('ranking', '95')]
# [('o', 'http://www.wikidata.org/entity/Q21622265'), ('oName', 'Akiko Ōmae'), ('ranking', '188')]
# [('o', 'http://www.wikidata.org/entity/Q21970595'), ('oName', 'Eléonora Molinaro'), ('ranking', '234')]
# [('o', 'http://www.wikidata.org/entity/Q21970595'), ('oName', 'Eléonora Molinaro'), ('ranking', '484')]
# [('o', 'http://www.wikidata.org/entity/Q312343'), ('oName', 'Milos Raonic'), ('ranking', '23')]
# [('o', 'http://www.wikidata.org/entity/Q312343'), ('oName', 'Milos Raonic'), ('ranking', '103')]
# [('o', 'http://www.wikidata.org/entity/Q22086227'), ('oName', 'Ellen Perez'), ('ranking', '40')]
# [('o', 'http://www.wikidata.org/entity/Q22086227'), ('oName', 'Ellen Perez'), ('ranking', '59')]
# [('o', 'http://www.wikidata.org/entity/Q22086227'), ('oName', 'Ellen Perez'), ('ranking', '162')]
# [('o', 'http://www.wikidata.org/entity/Q22958938'), ('oName', 'Alex de Minaur'), ('ranking', '18')]
# [('o', 'http://www.wikidata.org/entity/Q22958938'), ('oName', 'Alex de Minaur'), ('ranking', '134')]
# [('o', 'http://www.wikidata.org/entity/Q22953456'), ('oName', 'Agnese Gustmane'), ('ranking', '133')]
# [('o', 'http://www.wikidata.org/entity/Q22953456'), ('oName', 'Agnese Gustmane'), ('ranking', '155')]
# [('o', 'http://www.wikidata.org/entity/Q17747390'), ('oName', 'Quirine Lemoine'), ('ranking', '116')]
# [('o', 'http://www.wikidata.org/entity/Q239758'), ('oName', 'Arantxa Rus'), ('ranking', '59')]
# [('o', 'http://www.wikidata.org/entity/Q30778'), ('oName', 'Ashley Harkleroad'), ('ranking', '3')]
# [('o', 'http://www.wikidata.org/entity/Q30778'), ('oName', 'Ashley Harkleroad'), ('ranking', '39')]
# [('o', 'http://www.wikidata.org/entity/Q440093'), ('oName', 'Heidi El Tabakh'), ('ranking', '146')]
# [('o', 'http://www.wikidata.org/entity/Q440093'), ('oName', 'Heidi El Tabakh'), ('ranking', '173')]
# [('o', 'http://www.wikidata.org/entity/Q440162'), ('oName', 'Valeria Savinykh'), ('ranking', '98')]
# [('o', 'http://www.wikidata.org/entity/Q440162'), ('oName', 'Valeria Savinykh'), ('ranking', '99')]
# [('o', 'http://www.wikidata.org/entity/Q440443'), ('oName', 'Sandra Cecchini'), ('ranking', '15')]
# [('o', 'http://www.wikidata.org/entity/Q440443'), ('oName', 'Sandra Cecchini'), ('ranking', '22')]
# [('o', 'http://www.wikidata.org/entity/Q442087'), ('oName', 'Jelena Pandžić'), ('ranking', '136')]
# [('o', 'http://www.wikidata.org/entity/Q442087'), ('oName', 'Jelena Pandžić'), ('ranking', '226')]
# [('o', 'http://www.wikidata.org/entity/Q445602'), ('oName', 'Manuel Santana'), ('ranking', '145')]
# [('o', 'http://www.wikidata.org/entity/Q445602'), ('oName', 'Manuel Santana'), ('ranking', 'nodeID://b10407')]
# [('o', 'http://www.wikidata.org/entity/Q450264'), ('oName', 'Alycia Moulton'), ('ranking', '18')]
# [('o', 'http://www.wikidata.org/entity/Q450264'), ('oName', 'Alycia Moulton'), ('ranking', '28')]
# [('o', 'http://www.wikidata.org/entity/Q453385'), ('oName', 'Yuka Yoshida'), ('ranking', '51')]
# [('o', 'http://www.wikidata.org/entity/Q453385'), ('oName', 'Yuka Yoshida'), ('ranking', '52')]
# [('o', 'http://www.wikidata.org/entity/Q455136'), ('oName', 'Anders Järryd'), ('ranking', '1')]
# [('o', 'http://www.wikidata.org/entity/Q455136'), ('oName', 'Anders Järryd'), ('ranking', '5')]
# [('o', 'http://www.wikidata.org/entity/Q455165'), ('oName', 'Florencia Labat'), ('ranking', '26')]
# [('o', 'http://www.wikidata.org/entity/Q455165'), ('oName', 'Florencia Labat'), ('ranking', '27')]
# [('o', 'http://www.wikidata.org/entity/Q455411'), ('oName', 'Tom Okker'), ('ranking', '1')]
# [('o', 'http://www.wikidata.org/entity/Q455411'), ('oName', 'Tom Okker'), ('ranking', '3')]
# [('o', 'http://www.wikidata.org/entity/Q455453'), ('oName', 'Rika Hiraki'), ('ranking', '26')]
# [('o', 'http://www.wikidata.org/entity/Q455453'), ('oName', 'Rika Hiraki'), ('ranking', '72')]
# [('o', 'http://www.wikidata.org/entity/Q455507'), ('oName', 'Ana Jovanović'), ('ranking', '216')]
# [('o', 'http://www.wikidata.org/entity/Q455507'), ('oName', 'Ana Jovanović'), ('ranking', '285')]
# [('o', 'http://www.wikidata.org/entity/Q455711'), ('oName', 'Rachel McQuillan'), ('ranking', '15')]
# [('o', 'http://www.wikidata.org/entity/Q455711'), ('oName', 'Rachel McQuillan'), ('ranking', '28')]
# [('o', 'http://www.wikidata.org/entity/Q105868'), ('oName', 'Gabriela Sabatini'), ('ranking', '3')]
# [('o', 'http://www.wikidata.org/entity/Q310419'), ('oName', 'Nenad Zimonjić'), ('ranking', '1')]
# [('o', 'http://www.wikidata.org/entity/Q310419'), ('oName', 'Nenad Zimonjić'), ('ranking', '176')]
# [('o', 'http://www.wikidata.org/entity/Q53393'), ('oName', 'Jimmy Connors'), ('ranking', '1')]
# [('o', 'http://www.wikidata.org/entity/Q53393'), ('oName', 'Jimmy Connors'), ('ranking', '370')]
# [('o', 'http://www.wikidata.org/entity/Q545299'), ('oName', 'Dája Bedáňová'), ('ranking', '16')]
# [('o', 'http://www.wikidata.org/entity/Q545299'), ('oName', 'Dája Bedáňová'), ('ranking', '34')]
# [('o', 'http://www.wikidata.org/entity/Q552349'), ('oName', 'Jean-Julien Rojer'), ('ranking', '3')]
# [('o', 'http://www.wikidata.org/entity/Q552349'), ('oName', 'Jean-Julien Rojer'), ('ranking', '218')]
# [('o', 'http://www.wikidata.org/entity/Q230253'), ('oName', 'María José Martínez Sánchez'), ('ranking', '2')]
# [('o', 'http://www.wikidata.org/entity/Q230253'), ('oName', 'María José Martínez Sánchez'), ('ranking', '4')]
# [('o', 'http://www.wikidata.org/entity/Q230253'), ('oName', 'María José Martínez Sánchez'), ('ranking', '19')]
# [('o', 'http://www.wikidata.org/entity/Q233234'), ('oName', 'Virginia Wade'), ('ranking', '2')]
# [('o', 'http://www.wikidata.org/entity/Q233234'), ('oName', 'Virginia Wade'), ('ranking', '111')]
# [('o', 'http://www.wikidata.org/entity/Q258901'), ('oName', 'Henrieta Nagyová'), ('ranking', '37')]
# [('o', 'http://www.wikidata.org/entity/Q10118'), ('oName', 'Victoria Azarenka'), ('ranking', '1')]
# [('o', 'http://www.wikidata.org/entity/Q10118'), ('oName', 'Victoria Azarenka'), ('ranking', '7')]
# [('o', 'http://www.wikidata.org/entity/Q1616815'), ('oName', 'Nastassja Burnett'), ('ranking', '121')]
# [('o', 'http://www.wikidata.org/entity/Q1616815'), ('oName', 'Nastassja Burnett'), ('ranking', '380')]
# [('o', 'http://www.wikidata.org/entity/Q669082'), ('oName', 'Sonya Jeyaseelan'), ('ranking', '48')]
# 100

# %%
# write your queries
# Consider the country for sport property of the tennis player (NO Country of citizenship). 
# Return the countries with at least one player who was ranked 1 in the tennis ranking  (the result set must be a list of country IRI and label).

# Q41520 wimbledon

# P106('occupation'),
# Q10833314 ('tennis player')
# --P1352 ('ranking')--> ('o', '1')

# GETTING ALL TENNIS PLAYER
# GETTING their ranking
# -> FILTERING, only who was ranked 1

queryString = """

PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
SELECT DISTINCT ?o ?oName ?ranking
WHERE {
   # ?o wdt:P106 wd:Q10833314;
        wdt:P1352 ?ranking
   # get the label 
   OPTIONAL { ?o sc:name ?oName }.
   FILTER (xsd:integer(?ranking) = 1)
}
LIMIT 100

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('o', 'http://www.wikidata.org/entity/Q207352'), ('oName', 'Agnieszka Radwańska'), ('ranking', '1')]
# [('o', 'http://www.wikidata.org/entity/Q455136'), ('oName', 'Anders Järryd'), ('ranking', '1')]
# [('o', 'http://www.wikidata.org/entity/Q455411'), ('oName', 'Tom Okker'), ('ranking', '1')]
# [('o', 'http://www.wikidata.org/entity/Q310419'), ('oName', 'Nenad Zimonjić'), ('ranking', '1')]
# [('o', 'http://www.wikidata.org/entity/Q53393'), ('oName', 'Jimmy Connors'), ('ranking', '1')]
# [('o', 'http://www.wikidata.org/entity/Q10118'), ('oName', 'Victoria Azarenka'), ('ranking', '1')]
# [('o', 'http://www.wikidata.org/entity/Q13538'), ('oName', 'Henri Kontinen'), ('ranking', '1')]
# [('o', 'http://www.wikidata.org/entity/Q1743002'), ('oName', 'Robert Seguso'), ('ranking', '1')]
# [('o', 'http://www.wikidata.org/entity/Q189542'), ('oName', 'Stefan Edberg'), ('ranking', '1')]
# [('o', 'http://www.wikidata.org/entity/Q232566'), ('oName', 'Hsieh Su-wei'), ('ranking', '1')]
# [('o', 'http://www.wikidata.org/entity/Q289365'), ('oName', 'Karolína Plíšková'), ('ranking', '1')]
# [('o', 'http://www.wikidata.org/entity/Q30217670'), ('oName', 'Whitney Osuigwe'), ('ranking', '1')]
# [('o', 'http://www.wikidata.org/entity/Q11662'), ('oName', 'Steffi Graf'), ('ranking', '1')]
# [('o', 'http://www.wikidata.org/entity/Q182736'), ('oName', 'Ivan Lendl'), ('ranking', '1')]
# [('o', 'http://www.wikidata.org/entity/Q54584'), ('oName', 'Andy Roddick'), ('ranking', '1')]
# [('o', 'http://www.wikidata.org/entity/Q76334'), ('oName', 'Boris Becker'), ('ranking', '1')]
# [('o', 'http://www.wikidata.org/entity/Q132147'), ('oName', 'Sania Mirza'), ('ranking', '1')]
# [('o', 'http://www.wikidata.org/entity/Q229093'), ('oName', 'Virginia Ruano Pascual'), ('ranking', '1')]
# [('o', 'http://www.wikidata.org/entity/Q487182'), ('oName', 'Anastasia Pavlyuchenkova'), ('ranking', '1')]
# [('o', 'http://www.wikidata.org/entity/Q270414'), ('oName', 'Anne Smith'), ('ranking', '1')]
# [('o', 'http://www.wikidata.org/entity/Q298542'), ('oName', 'Daniel Nestor'), ('ranking', '1')]
# [('o', 'http://www.wikidata.org/entity/Q345626'), ('oName', 'Łukasz Kubot'), ('ranking', '1')]
# [('o', 'http://www.wikidata.org/entity/Q134720'), ('oName', 'Martina Hingis'), ('ranking', '1')]
# [('o', 'http://www.wikidata.org/entity/Q11685'), ('oName', 'Kim Clijsters'), ('ranking', '1')]
# [('o', 'http://www.wikidata.org/entity/Q221908'), ('oName', 'Yannick Noah'), ('ranking', '1')]
# [('o', 'http://www.wikidata.org/entity/Q229116'), ('oName', 'Katarina Srebotnik'), ('ranking', '1')]
# [('o', 'http://www.wikidata.org/entity/Q634844'), ('oName', 'Elena Vesnina'), ('ranking', '1')]
# [('o', 'http://www.wikidata.org/entity/Q180872'), ('oName', 'Amélie Mauresmo'), ('ranking', '1')]
# [('o', 'http://www.wikidata.org/entity/Q34276'), ('oName', 'Garbiñe Muguruza'), ('ranking', '1')]
# [('o', 'http://www.wikidata.org/entity/Q10129'), ('oName', 'Lisa Raymond'), ('ranking', '1')]
# [('o', 'http://www.wikidata.org/entity/Q11459'), ('oName', 'Serena Williams'), ('ranking', '1')]
# [('o', 'http://www.wikidata.org/entity/Q191766'), ('oName', 'Samantha Stosur'), ('ranking', '1')]
# [('o', 'http://www.wikidata.org/entity/Q230815'), ('oName', 'Rennae Stubbs'), ('ranking', '1')]
# [('o', 'http://www.wikidata.org/entity/Q104506'), ('oName', 'Björn Borg'), ('ranking', '1')]
# [('o', 'http://www.wikidata.org/entity/Q53340'), ('oName', 'Bob Bryan'), ('ranking', '1')]
# [('o', 'http://www.wikidata.org/entity/Q53342'), ('oName', 'Mike Bryan'), ('ranking', '1')]
# [('o', 'http://www.wikidata.org/entity/Q229100'), ('oName', 'Ai Sugiyama'), ('ranking', '1')]
# [('o', 'http://www.wikidata.org/entity/Q211428'), ('oName', 'Kaia Kanepi'), ('ranking', '1')]
# [('o', 'http://www.wikidata.org/entity/Q234624'), ('oName', 'Latisha Chan'), ('ranking', '1')]
# [('o', 'http://www.wikidata.org/entity/Q241320'), ('oName', 'Julie Halard-Decugis'), ('ranking', '1')]
# [('o', 'http://www.wikidata.org/entity/Q95162'), ('oName', 'Roberta Vinci'), ('ranking', '1')]
# [('o', 'http://www.wikidata.org/entity/Q921488'), ('oName', 'Juan Sebastián Cabal'), ('ranking', '1')]
# [('o', 'http://www.wikidata.org/entity/Q131120'), ('oName', 'Anna Kournikova'), ('ranking', '1')]
# [('o', 'http://www.wikidata.org/entity/Q1426'), ('oName', 'Roger Federer'), ('ranking', '1')]
# [('o', 'http://www.wikidata.org/entity/Q30767'), ('oName', 'Caroline Wozniacki'), ('ranking', '1')]
# [('o', 'http://www.wikidata.org/entity/Q5812'), ('oName', 'Novak Djokovic'), ('ranking', '1')]
# [('o', 'http://www.wikidata.org/entity/Q231960'), ('oName', 'Michaëlla Krajicek'), ('ranking', '1')]
# [('o', 'http://www.wikidata.org/entity/Q77178'), ('oName', 'Angelique Kerber'), ('ranking', '1')]
# [('o', 'http://www.wikidata.org/entity/Q11666'), ('oName', 'Maria Sharapova'), ('ranking', '1')]
# [('o', 'http://www.wikidata.org/entity/Q14286'), ('oName', 'Chris Evert'), ('ranking', '1')]
# [('o', 'http://www.wikidata.org/entity/Q229087'), ('oName', 'Peng Shuai'), ('ranking', '1')]
# [('o', 'http://www.wikidata.org/entity/Q230156'), ('oName', 'Simona Halep'), ('ranking', '1')]
# [('o', 'http://www.wikidata.org/entity/Q9446'), ('oName', 'Pete Sampras'), ('ranking', '1')]
# [('o', 'http://www.wikidata.org/entity/Q188080'), ('oName', 'Arantxa Sánchez Vicario'), ('ranking', '1')]
# [('o', 'http://www.wikidata.org/entity/Q233243'), ('oName', 'Natasha Zvereva'), ('ranking', '1')]
# [('o', 'http://www.wikidata.org/entity/Q233332'), ('oName', 'Gigi Fernández'), ('ranking', '1')]
# [('o', 'http://www.wikidata.org/entity/Q133318'), ('oName', 'Marat Safin'), ('ranking', '1')]
# [('o', 'http://www.wikidata.org/entity/Q429013'), ('oName', 'Emilio Sánchez'), ('ranking', '1')]
# [('o', 'http://www.wikidata.org/entity/Q11682'), ('oName', 'Justine Henin'), ('ranking', '1')]
# [('o', 'http://www.wikidata.org/entity/Q193361'), ('oName', 'Carlos Moyá'), ('ranking', '1')]
# [('o', 'http://www.wikidata.org/entity/Q1355458'), ('oName', 'Robert Farah'), ('ranking', '1')]
# [('o', 'http://www.wikidata.org/entity/Q229151'), ('oName', 'Helena Suková'), ('ranking', '1')]
# [('o', 'http://www.wikidata.org/entity/Q53396'), ('oName', 'Jim Courier'), ('ranking', '1')]
# [('o', 'http://www.wikidata.org/entity/Q10132'), ('oName', 'Rafael Nadal'), ('ranking', '1')]
# [('o', 'http://www.wikidata.org/entity/Q234480'), ('oName', 'Květa Peschke'), ('ranking', '1')]
# [('o', 'http://www.wikidata.org/entity/Q173633'), ('oName', 'Monica Seles'), ('ranking', '1')]
# [('o', 'http://www.wikidata.org/entity/Q11677'), ('oName', 'Lindsay Davenport'), ('ranking', '1')]
# [('o', 'http://www.wikidata.org/entity/Q180104'), ('oName', 'Lleyton Hewitt'), ('ranking', '1')]
# [('o', 'http://www.wikidata.org/entity/Q221359'), ('oName', 'Max Mirnyi'), ('ranking', '1')]
# [('o', 'http://www.wikidata.org/entity/Q229121'), ('oName', 'Jana Novotná'), ('ranking', '1')]
# [('o', 'http://www.wikidata.org/entity/Q229128'), ('oName', 'Cara Black'), ('ranking', '1')]
# [('o', 'http://www.wikidata.org/entity/Q242959'), ('oName', 'Kristina Mladenovic'), ('ranking', '1')]
# [('o', 'http://www.wikidata.org/entity/Q560151'), ('oName', 'Jacco Eltingh'), ('ranking', '1')]
# [('o', 'http://www.wikidata.org/entity/Q185722'), ('oName', 'Juan Carlos Ferrero'), ('ranking', '1')]
# [('o', 'http://www.wikidata.org/entity/Q228989'), ('oName', 'Lucie Šafářová'), ('ranking', '1')]
# [('o', 'http://www.wikidata.org/entity/Q11680'), ('oName', 'Jennifer Capriati'), ('ranking', '1')]
# [('o', 'http://www.wikidata.org/entity/Q228559'), ('oName', 'Evonne Goolagong Cawley'), ('ranking', '1')]
# [('o', 'http://www.wikidata.org/entity/Q11578'), ('oName', 'Venus Williams'), ('ranking', '1')]
# [('o', 'http://www.wikidata.org/entity/Q54654'), ('oName', 'Pam Shriver'), ('ranking', '1')]
# [('o', 'http://www.wikidata.org/entity/Q240695'), ('oName', 'Larisa Neiland'), ('ranking', '1')]
# [('o', 'http://www.wikidata.org/entity/Q1029664'), ('oName', 'Dinara Safina'), ('ranking', '1')]
# [('o', 'http://www.wikidata.org/entity/Q207528'), ('oName', 'Flavia Pennetta'), ('ranking', '1')]
# [('o', 'http://www.wikidata.org/entity/Q207705'), ('oName', 'Yevgeny Kafelnikov'), ('ranking', '1')]
# [('o', 'http://www.wikidata.org/entity/Q225589'), ('oName', 'Corina Morariu'), ('ranking', '1')]
# [('o', 'http://www.wikidata.org/entity/Q30758'), ('oName', 'Ana Ivanovic'), ('ranking', '1')]
# [('o', 'http://www.wikidata.org/entity/Q204068'), ('oName', 'Patrick Rafter'), ('ranking', '1')]
# [('o', 'http://www.wikidata.org/entity/Q229474'), ('oName', 'Paola Suárez'), ('ranking', '1')]
# [('o', 'http://www.wikidata.org/entity/Q29441'), ('oName', 'Paul Haarhuis'), ('ranking', '1')]
# [('o', 'http://www.wikidata.org/entity/Q317974'), ('oName', 'Nicolas Mahut'), ('ranking', '1')]
# [('o', 'http://www.wikidata.org/entity/Q270249'), ('oName', 'Elina Svitolina'), ('ranking', '1')]
# [('o', 'http://www.wikidata.org/entity/Q312464'), ('oName', 'John Newcombe'), ('ranking', '1')]
# [('o', 'http://www.wikidata.org/entity/Q54690'), ('oName', 'Ellsworth Vines'), ('ranking', '1')]
# [('o', 'http://www.wikidata.org/entity/Q190723'), ('oName', 'Gustavo Kuerten'), ('ranking', '1')]
# [('o', 'http://www.wikidata.org/entity/Q54545'), ('oName', 'Martina Navratilova'), ('ranking', '1')]
# [('o', 'http://www.wikidata.org/entity/Q426049'), ('oName', 'John Fitzgerald'), ('ranking', '1')]
# [('o', 'http://www.wikidata.org/entity/Q11052500'), ('oName', 'Barbora Krejčíková'), ('ranking', '1')]
# [('o', 'http://www.wikidata.org/entity/Q84056'), ('oName', 'Ashleigh Barty'), ('ranking', '1')]
# [('o', 'http://www.wikidata.org/entity/Q54537'), ('oName', 'Bethanie Mattek-Sands'), ('ranking', '1')]
# [('o', 'http://www.wikidata.org/entity/Q953688'), ('oName', 'Ekaterina Valeryevna Makarova'), ('ranking', '1')]
# [('o', 'http://www.wikidata.org/entity/Q3720044'), ('oName', 'Kateřina Siniaková'), ('ranking', '1')]
# 100

# %%
# write your queries
# Consider the country for sport property of the tennis player (NO Country of citizenship). 
# Return the countries with at least one player who was ranked 1 in the tennis ranking  (the result set must be a list of country IRI and label).

# Q41520 wimbledon

# P106('occupation'),
# Q10833314 ('tennis player')
# --P1352 ('ranking')--> ('o', '1')

# GETTING ALL TENNIS PLAYER
# GETTING their ranking
# FILTERING, only who was ranked 1
# -> getting their countryForSport

queryString = """

PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
SELECT DISTINCT ?o ?oName ?ranking ?countryForSport ?countryForSportName
WHERE {
   # ?o wdt:P106 wd:Q10833314;
        wdt:P1352 ?ranking;
        wdt:P1532 ?countryForSport.
   # get the label 
   # ?countryForSport sc:name ?countryForSportName
   OPTIONAL { ?o sc:name ?oName }.
   FILTER (xsd:integer(?ranking) = 1)
}
LIMIT 100

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('o', 'http://www.wikidata.org/entity/Q232566'), ('oName', 'Hsieh Su-wei'), ('ranking', '1'), ('countryForSport', 'http://www.wikidata.org/entity/Q216923'), ('countryForSportName', 'Chinese Taipei')]
# [('o', 'http://www.wikidata.org/entity/Q11662'), ('oName', 'Steffi Graf'), ('ranking', '1'), ('countryForSport', 'http://www.wikidata.org/entity/Q183'), ('countryForSportName', 'Germany')]
# [('o', 'http://www.wikidata.org/entity/Q76334'), ('oName', 'Boris Becker'), ('ranking', '1'), ('countryForSport', 'http://www.wikidata.org/entity/Q183'), ('countryForSportName', 'Germany')]
# [('o', 'http://www.wikidata.org/entity/Q10118'), ('oName', 'Victoria Azarenka'), ('ranking', '1'), ('countryForSport', 'http://www.wikidata.org/entity/Q184'), ('countryForSportName', 'Belarus')]
# [('o', 'http://www.wikidata.org/entity/Q289365'), ('oName', 'Karolína Plíšková'), ('ranking', '1'), ('countryForSport', 'http://www.wikidata.org/entity/Q213'), ('countryForSportName', 'Czech Republic')]
# [('o', 'http://www.wikidata.org/entity/Q30217670'), ('oName', 'Whitney Osuigwe'), ('ranking', '1'), ('countryForSport', 'http://www.wikidata.org/entity/Q30'), ('countryForSportName', 'United States of America')]
# [('o', 'http://www.wikidata.org/entity/Q53393'), ('oName', 'Jimmy Connors'), ('ranking', '1'), ('countryForSport', 'http://www.wikidata.org/entity/Q30'), ('countryForSportName', 'United States of America')]
# [('o', 'http://www.wikidata.org/entity/Q1743002'), ('oName', 'Robert Seguso'), ('ranking', '1'), ('countryForSport', 'http://www.wikidata.org/entity/Q30'), ('countryForSportName', 'United States of America')]
# [('o', 'http://www.wikidata.org/entity/Q182736'), ('oName', 'Ivan Lendl'), ('ranking', '1'), ('countryForSport', 'http://www.wikidata.org/entity/Q30'), ('countryForSportName', 'United States of America')]
# [('o', 'http://www.wikidata.org/entity/Q13538'), ('oName', 'Henri Kontinen'), ('ranking', '1'), ('countryForSport', 'http://www.wikidata.org/entity/Q33'), ('countryForSportName', 'Finland')]
# [('o', 'http://www.wikidata.org/entity/Q189542'), ('oName', 'Stefan Edberg'), ('ranking', '1'), ('countryForSport', 'http://www.wikidata.org/entity/Q34'), ('countryForSportName', 'Sweden')]
# [('o', 'http://www.wikidata.org/entity/Q455136'), ('oName', 'Anders Järryd'), ('ranking', '1'), ('countryForSport', 'http://www.wikidata.org/entity/Q34'), ('countryForSportName', 'Sweden')]
# [('o', 'http://www.wikidata.org/entity/Q207352'), ('oName', 'Agnieszka Radwańska'), ('ranking', '1'), ('countryForSport', 'http://www.wikidata.org/entity/Q36'), ('countryForSportName', 'Poland')]
# [('o', 'http://www.wikidata.org/entity/Q132147'), ('oName', 'Sania Mirza'), ('ranking', '1'), ('countryForSport', 'http://www.wikidata.org/entity/Q668'), ('countryForSportName', 'India')]
# [('o', 'http://www.wikidata.org/entity/Q182736'), ('oName', 'Ivan Lendl'), ('ranking', '1'), ('countryForSport', 'http://www.wikidata.org/entity/Q33946'), ('countryForSportName', 'Czechoslovakia')]
# [('o', 'http://www.wikidata.org/entity/Q487182'), ('oName', 'Anastasia Pavlyuchenkova'), ('ranking', '1'), ('countryForSport', 'http://www.wikidata.org/entity/Q159'), ('countryForSportName', 'Russia')]
# [('o', 'http://www.wikidata.org/entity/Q229093'), ('oName', 'Virginia Ruano Pascual'), ('ranking', '1'), ('countryForSport', 'http://www.wikidata.org/entity/Q29'), ('countryForSportName', 'Spain')]
# [('o', 'http://www.wikidata.org/entity/Q270414'), ('oName', 'Anne Smith'), ('ranking', '1'), ('countryForSport', 'http://www.wikidata.org/entity/Q30'), ('countryForSportName', 'United States of America')]
# [('o', 'http://www.wikidata.org/entity/Q221908'), ('oName', 'Yannick Noah'), ('ranking', '1'), ('countryForSport', 'http://www.wikidata.org/entity/Q142'), ('countryForSportName', 'France')]
# [('o', 'http://www.wikidata.org/entity/Q634844'), ('oName', 'Elena Vesnina'), ('ranking', '1'), ('countryForSport', 'http://www.wikidata.org/entity/Q159'), ('countryForSportName', 'Russia')]
# [('o', 'http://www.wikidata.org/entity/Q298542'), ('oName', 'Daniel Nestor'), ('ranking', '1'), ('countryForSport', 'http://www.wikidata.org/entity/Q16'), ('countryForSportName', 'Canada')]
# [('o', 'http://www.wikidata.org/entity/Q229116'), ('oName', 'Katarina Srebotnik'), ('ranking', '1'), ('countryForSport', 'http://www.wikidata.org/entity/Q215'), ('countryForSportName', 'Slovenia')]
# [('o', 'http://www.wikidata.org/entity/Q11685'), ('oName', 'Kim Clijsters'), ('ranking', '1'), ('countryForSport', 'http://www.wikidata.org/entity/Q31'), ('countryForSportName', 'Belgium')]
# [('o', 'http://www.wikidata.org/entity/Q345626'), ('oName', 'Łukasz Kubot'), ('ranking', '1'), ('countryForSport', 'http://www.wikidata.org/entity/Q36'), ('countryForSportName', 'Poland')]
# [('o', 'http://www.wikidata.org/entity/Q134720'), ('oName', 'Martina Hingis'), ('ranking', '1'), ('countryForSport', 'http://www.wikidata.org/entity/Q39'), ('countryForSportName', 'Switzerland')]
# [('o', 'http://www.wikidata.org/entity/Q234624'), ('oName', 'Latisha Chan'), ('ranking', '1'), ('countryForSport', 'http://www.wikidata.org/entity/Q216923'), ('countryForSportName', 'Chinese Taipei')]
# [('o', 'http://www.wikidata.org/entity/Q241320'), ('oName', 'Julie Halard-Decugis'), ('ranking', '1'), ('countryForSport', 'http://www.wikidata.org/entity/Q142'), ('countryForSportName', 'France')]
# [('o', 'http://www.wikidata.org/entity/Q180872'), ('oName', 'Amélie Mauresmo'), ('ranking', '1'), ('countryForSport', 'http://www.wikidata.org/entity/Q142'), ('countryForSportName', 'France')]
# [('o', 'http://www.wikidata.org/entity/Q131120'), ('oName', 'Anna Kournikova'), ('ranking', '1'), ('countryForSport', 'http://www.wikidata.org/entity/Q159'), ('countryForSportName', 'Russia')]
# [('o', 'http://www.wikidata.org/entity/Q229100'), ('oName', 'Ai Sugiyama'), ('ranking', '1'), ('countryForSport', 'http://www.wikidata.org/entity/Q17'), ('countryForSportName', 'Japan')]
# [('o', 'http://www.wikidata.org/entity/Q211428'), ('oName', 'Kaia Kanepi'), ('ranking', '1'), ('countryForSport', 'http://www.wikidata.org/entity/Q191'), ('countryForSportName', 'Estonia')]
# [('o', 'http://www.wikidata.org/entity/Q34276'), ('oName', 'Garbiñe Muguruza'), ('ranking', '1'), ('countryForSport', 'http://www.wikidata.org/entity/Q29'), ('countryForSportName', 'Spain')]
# [('o', 'http://www.wikidata.org/entity/Q10129'), ('oName', 'Lisa Raymond'), ('ranking', '1'), ('countryForSport', 'http://www.wikidata.org/entity/Q30'), ('countryForSportName', 'United States of America')]
# [('o', 'http://www.wikidata.org/entity/Q11459'), ('oName', 'Serena Williams'), ('ranking', '1'), ('countryForSport', 'http://www.wikidata.org/entity/Q30'), ('countryForSportName', 'United States of America')]
# [('o', 'http://www.wikidata.org/entity/Q104506'), ('oName', 'Björn Borg'), ('ranking', '1'), ('countryForSport', 'http://www.wikidata.org/entity/Q34'), ('countryForSportName', 'Sweden')]
# [('o', 'http://www.wikidata.org/entity/Q30767'), ('oName', 'Caroline Wozniacki'), ('ranking', '1'), ('countryForSport', 'http://www.wikidata.org/entity/Q35'), ('countryForSportName', 'Denmark')]
# [('o', 'http://www.wikidata.org/entity/Q95162'), ('oName', 'Roberta Vinci'), ('ranking', '1'), ('countryForSport', 'http://www.wikidata.org/entity/Q38'), ('countryForSportName', 'Italy')]
# [('o', 'http://www.wikidata.org/entity/Q1426'), ('oName', 'Roger Federer'), ('ranking', '1'), ('countryForSport', 'http://www.wikidata.org/entity/Q39'), ('countryForSportName', 'Switzerland')]
# [('o', 'http://www.wikidata.org/entity/Q191766'), ('oName', 'Samantha Stosur'), ('ranking', '1'), ('countryForSport', 'http://www.wikidata.org/entity/Q408'), ('countryForSportName', 'Australia')]
# [('o', 'http://www.wikidata.org/entity/Q921488'), ('oName', 'Juan Sebastián Cabal'), ('ranking', '1'), ('countryForSport', 'http://www.wikidata.org/entity/Q739'), ('countryForSportName', 'Colombia')]
# [('o', 'http://www.wikidata.org/entity/Q11666'), ('oName', 'Maria Sharapova'), ('ranking', '1'), ('countryForSport', 'http://www.wikidata.org/entity/Q159'), ('countryForSportName', 'Russia')]
# [('o', 'http://www.wikidata.org/entity/Q77178'), ('oName', 'Angelique Kerber'), ('ranking', '1'), ('countryForSport', 'http://www.wikidata.org/entity/Q183'), ('countryForSportName', 'Germany')]
# [('o', 'http://www.wikidata.org/entity/Q231960'), ('oName', 'Michaëlla Krajicek'), ('ranking', '1'), ('countryForSport', 'http://www.wikidata.org/entity/Q29999'), ('countryForSportName', 'Kingdom of the Netherlands')]
# [('o', 'http://www.wikidata.org/entity/Q5812'), ('oName', 'Novak Djokovic'), ('ranking', '1'), ('countryForSport', 'http://www.wikidata.org/entity/Q403'), ('countryForSportName', 'Serbia')]
# [('o', 'http://www.wikidata.org/entity/Q229087'), ('oName', 'Peng Shuai'), ('ranking', '1'), ('countryForSport', 'http://www.wikidata.org/entity/Q148'), ('countryForSportName', "People's Republic of China")]
# [('o', 'http://www.wikidata.org/entity/Q133318'), ('oName', 'Marat Safin'), ('ranking', '1'), ('countryForSport', 'http://www.wikidata.org/entity/Q159'), ('countryForSportName', 'Russia')]
# [('o', 'http://www.wikidata.org/entity/Q233243'), ('oName', 'Natasha Zvereva'), ('ranking', '1'), ('countryForSport', 'http://www.wikidata.org/entity/Q184'), ('countryForSportName', 'Belarus')]
# [('o', 'http://www.wikidata.org/entity/Q230156'), ('oName', 'Simona Halep'), ('ranking', '1'), ('countryForSport', 'http://www.wikidata.org/entity/Q218'), ('countryForSportName', 'Romania')]
# [('o', 'http://www.wikidata.org/entity/Q429013'), ('oName', 'Emilio Sánchez'), ('ranking', '1'), ('countryForSport', 'http://www.wikidata.org/entity/Q29'), ('countryForSportName', 'Spain')]
# [('o', 'http://www.wikidata.org/entity/Q188080'), ('oName', 'Arantxa Sánchez Vicario'), ('ranking', '1'), ('countryForSport', 'http://www.wikidata.org/entity/Q29'), ('countryForSportName', 'Spain')]
# [('o', 'http://www.wikidata.org/entity/Q233332'), ('oName', 'Gigi Fernández'), ('ranking', '1'), ('countryForSport', 'http://www.wikidata.org/entity/Q30'), ('countryForSportName', 'United States of America')]
# [('o', 'http://www.wikidata.org/entity/Q14286'), ('oName', 'Chris Evert'), ('ranking', '1'), ('countryForSport', 'http://www.wikidata.org/entity/Q30'), ('countryForSportName', 'United States of America')]
# [('o', 'http://www.wikidata.org/entity/Q242959'), ('oName', 'Kristina Mladenovic'), ('ranking', '1'), ('countryForSport', 'http://www.wikidata.org/entity/Q142'), ('countryForSportName', 'France')]
# [('o', 'http://www.wikidata.org/entity/Q240695'), ('oName', 'Larisa Neiland'), ('ranking', '1'), ('countryForSport', 'http://www.wikidata.org/entity/Q15180'), ('countryForSportName', 'Soviet Union')]
# [('o', 'http://www.wikidata.org/entity/Q1029664'), ('oName', 'Dinara Safina'), ('ranking', '1'), ('countryForSport', 'http://www.wikidata.org/entity/Q159'), ('countryForSportName', 'Russia')]
# [('o', 'http://www.wikidata.org/entity/Q207705'), ('oName', 'Yevgeny Kafelnikov'), ('ranking', '1'), ('countryForSport', 'http://www.wikidata.org/entity/Q159'), ('countryForSportName', 'Russia')]
# [('o', 'http://www.wikidata.org/entity/Q221359'), ('oName', 'Max Mirnyi'), ('ranking', '1'), ('countryForSport', 'http://www.wikidata.org/entity/Q184'), ('countryForSportName', 'Belarus')]
# [('o', 'http://www.wikidata.org/entity/Q240695'), ('oName', 'Larisa Neiland'), ('ranking', '1'), ('countryForSport', 'http://www.wikidata.org/entity/Q211'), ('countryForSportName', 'Latvia')]
# [('o', 'http://www.wikidata.org/entity/Q234480'), ('oName', 'Květa Peschke'), ('ranking', '1'), ('countryForSport', 'http://www.wikidata.org/entity/Q213'), ('countryForSportName', 'Czech Republic')]
# [('o', 'http://www.wikidata.org/entity/Q228989'), ('oName', 'Lucie Šafářová'), ('ranking', '1'), ('countryForSport', 'http://www.wikidata.org/entity/Q213'), ('countryForSportName', 'Czech Republic')]
# [('o', 'http://www.wikidata.org/entity/Q229121'), ('oName', 'Jana Novotná'), ('ranking', '1'), ('countryForSport', 'http://www.wikidata.org/entity/Q213'), ('countryForSportName', 'Czech Republic')]
# [('o', 'http://www.wikidata.org/entity/Q229151'), ('oName', 'Helena Suková'), ('ranking', '1'), ('countryForSport', 'http://www.wikidata.org/entity/Q213'), ('countryForSportName', 'Czech Republic')]
# [('o', 'http://www.wikidata.org/entity/Q185722'), ('oName', 'Juan Carlos Ferrero'), ('ranking', '1'), ('countryForSport', 'http://www.wikidata.org/entity/Q29'), ('countryForSportName', 'Spain')]
# [('o', 'http://www.wikidata.org/entity/Q193361'), ('oName', 'Carlos Moyá'), ('ranking', '1'), ('countryForSport', 'http://www.wikidata.org/entity/Q29'), ('countryForSportName', 'Spain')]
# [('o', 'http://www.wikidata.org/entity/Q10132'), ('oName', 'Rafael Nadal'), ('ranking', '1'), ('countryForSport', 'http://www.wikidata.org/entity/Q29'), ('countryForSportName', 'Spain')]
# [('o', 'http://www.wikidata.org/entity/Q11677'), ('oName', 'Lindsay Davenport'), ('ranking', '1'), ('countryForSport', 'http://www.wikidata.org/entity/Q30'), ('countryForSportName', 'United States of America')]
# [('o', 'http://www.wikidata.org/entity/Q54654'), ('oName', 'Pam Shriver'), ('ranking', '1'), ('countryForSport', 'http://www.wikidata.org/entity/Q30'), ('countryForSportName', 'United States of America')]
# [('o', 'http://www.wikidata.org/entity/Q225589'), ('oName', 'Corina Morariu'), ('ranking', '1'), ('countryForSport', 'http://www.wikidata.org/entity/Q30'), ('countryForSportName', 'United States of America')]
# [('o', 'http://www.wikidata.org/entity/Q173633'), ('oName', 'Monica Seles'), ('ranking', '1'), ('countryForSport', 'http://www.wikidata.org/entity/Q30'), ('countryForSportName', 'United States of America')]
# [('o', 'http://www.wikidata.org/entity/Q11578'), ('oName', 'Venus Williams'), ('ranking', '1'), ('countryForSport', 'http://www.wikidata.org/entity/Q30'), ('countryForSportName', 'United States of America')]
# [('o', 'http://www.wikidata.org/entity/Q11680'), ('oName', 'Jennifer Capriati'), ('ranking', '1'), ('countryForSport', 'http://www.wikidata.org/entity/Q30'), ('countryForSportName', 'United States of America')]
# [('o', 'http://www.wikidata.org/entity/Q11682'), ('oName', 'Justine Henin'), ('ranking', '1'), ('countryForSport', 'http://www.wikidata.org/entity/Q31'), ('countryForSportName', 'Belgium')]
# [('o', 'http://www.wikidata.org/entity/Q207528'), ('oName', 'Flavia Pennetta'), ('ranking', '1'), ('countryForSport', 'http://www.wikidata.org/entity/Q38'), ('countryForSportName', 'Italy')]
# [('o', 'http://www.wikidata.org/entity/Q30758'), ('oName', 'Ana Ivanovic'), ('ranking', '1'), ('countryForSport', 'http://www.wikidata.org/entity/Q403'), ('countryForSportName', 'Serbia')]
# [('o', 'http://www.wikidata.org/entity/Q228559'), ('oName', 'Evonne Goolagong Cawley'), ('ranking', '1'), ('countryForSport', 'http://www.wikidata.org/entity/Q408'), ('countryForSportName', 'Australia')]
# [('o', 'http://www.wikidata.org/entity/Q1355458'), ('oName', 'Robert Farah'), ('ranking', '1'), ('countryForSport', 'http://www.wikidata.org/entity/Q739'), ('countryForSportName', 'Colombia')]
# [('o', 'http://www.wikidata.org/entity/Q173633'), ('oName', 'Monica Seles'), ('ranking', '1'), ('countryForSport', 'http://www.wikidata.org/entity/Q83286'), ('countryForSportName', 'Socialist Federal Republic of Yugoslavia')]
# [('o', 'http://www.wikidata.org/entity/Q229121'), ('oName', 'Jana Novotná'), ('ranking', '1'), ('countryForSport', 'http://www.wikidata.org/entity/Q33946'), ('countryForSportName', 'Czechoslovakia')]
# [('o', 'http://www.wikidata.org/entity/Q317974'), ('oName', 'Nicolas Mahut'), ('ranking', '1'), ('countryForSport', 'http://www.wikidata.org/entity/Q142'), ('countryForSportName', 'France')]
# [('o', 'http://www.wikidata.org/entity/Q503183'), ('oName', 'Arthur Gore'), ('ranking', '1'), ('countryForSport', 'http://www.wikidata.org/entity/Q145'), ('countryForSportName', 'United Kingdom')]
# [('o', 'http://www.wikidata.org/entity/Q190723'), ('oName', 'Gustavo Kuerten'), ('ranking', '1'), ('countryForSport', 'http://www.wikidata.org/entity/Q155'), ('countryForSportName', 'Brazil')]
# [('o', 'http://www.wikidata.org/entity/Q953688'), ('oName', 'Ekaterina Valeryevna Makarova'), ('ranking', '1'), ('countryForSport', 'http://www.wikidata.org/entity/Q159'), ('countryForSportName', 'Russia')]
# [('o', 'http://www.wikidata.org/entity/Q17466583'), ('oName', 'Naomi Osaka'), ('ranking', '1'), ('countryForSport', 'http://www.wikidata.org/entity/Q17'), ('countryForSportName', 'Japan')]
# [('o', 'http://www.wikidata.org/entity/Q270249'), ('oName', 'Elina Svitolina'), ('ranking', '1'), ('countryForSport', 'http://www.wikidata.org/entity/Q212'), ('countryForSportName', 'Ukraine')]
# [('o', 'http://www.wikidata.org/entity/Q3720044'), ('oName', 'Kateřina Siniaková'), ('ranking', '1'), ('countryForSport', 'http://www.wikidata.org/entity/Q213'), ('countryForSportName', 'Czech Republic')]
# [('o', 'http://www.wikidata.org/entity/Q11052500'), ('oName', 'Barbora Krejčíková'), ('ranking', '1'), ('countryForSport', 'http://www.wikidata.org/entity/Q213'), ('countryForSportName', 'Czech Republic')]
# [('o', 'http://www.wikidata.org/entity/Q54545'), ('oName', 'Martina Navratilova'), ('ranking', '1'), ('countryForSport', 'http://www.wikidata.org/entity/Q213'), ('countryForSportName', 'Czech Republic')]
# [('o', 'http://www.wikidata.org/entity/Q1588571'), ('oName', 'Mate Pavić'), ('ranking', '1'), ('countryForSport', 'http://www.wikidata.org/entity/Q224'), ('countryForSportName', 'Croatia')]
# [('o', 'http://www.wikidata.org/entity/Q54537'), ('oName', 'Bethanie Mattek-Sands'), ('ranking', '1'), ('countryForSport', 'http://www.wikidata.org/entity/Q30'), ('countryForSportName', 'United States of America')]
# [('o', 'http://www.wikidata.org/entity/Q54545'), ('oName', 'Martina Navratilova'), ('ranking', '1'), ('countryForSport', 'http://www.wikidata.org/entity/Q30'), ('countryForSportName', 'United States of America')]
# [('o', 'http://www.wikidata.org/entity/Q426049'), ('oName', 'John Fitzgerald'), ('ranking', '1'), ('countryForSport', 'http://www.wikidata.org/entity/Q408'), ('countryForSportName', 'Australia')]
# [('o', 'http://www.wikidata.org/entity/Q84056'), ('oName', 'Ashleigh Barty'), ('ranking', '1'), ('countryForSport', 'http://www.wikidata.org/entity/Q408'), ('countryForSportName', 'Australia')]
# [('o', 'http://www.wikidata.org/entity/Q54545'), ('oName', 'Martina Navratilova'), ('ranking', '1'), ('countryForSport', 'http://www.wikidata.org/entity/Q33946'), ('countryForSportName', 'Czechoslovakia')]
# [('o', 'http://www.wikidata.org/entity/Q41799108'), ('oName', 'Wang Xiyu'), ('ranking', '1'), ('countryForSport', 'http://www.wikidata.org/entity/Q148'), ('countryForSportName', "People's Republic of China")]
# [('o', 'http://www.wikidata.org/entity/Q24955766'), ('oName', 'Anastasija Potapova'), ('ranking', '1'), ('countryForSport', 'http://www.wikidata.org/entity/Q159'), ('countryForSportName', 'Russia')]
# [('o', 'http://www.wikidata.org/entity/Q608657'), ('oName', 'Ken Flach'), ('ranking', '1'), ('countryForSport', 'http://www.wikidata.org/entity/Q30'), ('countryForSportName', 'United States of America')]
# [('o', 'http://www.wikidata.org/entity/Q524807'), ('oName', 'JoAnne Russell'), ('ranking', '1'), ('countryForSport', 'http://www.wikidata.org/entity/Q30'), ('countryForSportName', 'United States of America')]
# [('o', 'http://www.wikidata.org/entity/Q53326'), ('oName', 'Tracy Austin'), ('ranking', '1'), ('countryForSport', 'http://www.wikidata.org/entity/Q30'), ('countryForSportName', 'United States of America')]
# [('o', 'http://www.wikidata.org/entity/Q20898017'), ('oName', 'Claire Liu'), ('ranking', '1'), ('countryForSport', 'http://www.wikidata.org/entity/Q30'), ('countryForSportName', 'United States of America')]
# 99

# %%
# write your queries
# Consider the country for sport property of the tennis player (NO Country of citizenship). 
# Return the countries with at least one player who was ranked 1 in the tennis ranking  (the result set must be a list of country IRI and label).

# Q41520 wimbledon

# P106('occupation'),
# Q10833314 ('tennis player')
# --P1352 ('ranking')--> ('o', '1')

# GETTING ALL TENNIS PLAYER
# GETTING their ranking
# FILTERING, only who was ranked 1
# getting their countryForSport
# RETURNing distinc countries

queryString = """

PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
SELECT DISTINCT ?countryForSport ?countryForSportName (COUNT(*) as ?tot)
WHERE {
   # ?o wdt:P106 wd:Q10833314;
        wdt:P1352 ?ranking;
        wdt:P1532 ?countryForSport.
   # get the label 
   # ?countryForSport sc:name ?countryForSportName.
   OPTIONAL { ?o sc:name ?oName }.
   FILTER (xsd:integer(?ranking) = 1)
}
GROUP BY ?countryForSport ?countryForSportName
ORDER BY desc (?tot)
LIMIT 100

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('countryForSport', 'http://www.wikidata.org/entity/Q30'), ('countryForSportName', 'United States of America'), ('tot', '21')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q159'), ('countryForSportName', 'Russia'), ('tot', '9')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q213'), ('countryForSportName', 'Czech Republic'), ('tot', '8')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q29'), ('countryForSportName', 'Spain'), ('tot', '7')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q142'), ('countryForSportName', 'France'), ('tot', '5')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q408'), ('countryForSportName', 'Australia'), ('tot', '4')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q183'), ('countryForSportName', 'Germany'), ('tot', '3')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q34'), ('countryForSportName', 'Sweden'), ('tot', '3')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q184'), ('countryForSportName', 'Belarus'), ('tot', '3')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q33946'), ('countryForSportName', 'Czechoslovakia'), ('tot', '3')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q38'), ('countryForSportName', 'Italy'), ('tot', '2')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q216923'), ('countryForSportName', 'Chinese Taipei'), ('tot', '2')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q31'), ('countryForSportName', 'Belgium'), ('tot', '2')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q403'), ('countryForSportName', 'Serbia'), ('tot', '2')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q148'), ('countryForSportName', "People's Republic of China"), ('tot', '2')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q36'), ('countryForSportName', 'Poland'), ('tot', '2')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q17'), ('countryForSportName', 'Japan'), ('tot', '2')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q39'), ('countryForSportName', 'Switzerland'), ('tot', '2')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q739'), ('countryForSportName', 'Colombia'), ('tot', '2')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q215'), ('countryForSportName', 'Slovenia'), ('tot', '1')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q218'), ('countryForSportName', 'Romania'), ('tot', '1')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q16'), ('countryForSportName', 'Canada'), ('tot', '1')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q83286'), ('countryForSportName', 'Socialist Federal Republic of Yugoslavia'), ('tot', '1')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q155'), ('countryForSportName', 'Brazil'), ('tot', '1')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q212'), ('countryForSportName', 'Ukraine'), ('tot', '1')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q33'), ('countryForSportName', 'Finland'), ('tot', '1')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q668'), ('countryForSportName', 'India'), ('tot', '1')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q224'), ('countryForSportName', 'Croatia'), ('tot', '1')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q29999'), ('countryForSportName', 'Kingdom of the Netherlands'), ('tot', '1')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q35'), ('countryForSportName', 'Denmark'), ('tot', '1')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q191'), ('countryForSportName', 'Estonia'), ('tot', '1')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q15180'), ('countryForSportName', 'Soviet Union'), ('tot', '1')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q211'), ('countryForSportName', 'Latvia'), ('tot', '1')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q145'), ('countryForSportName', 'United Kingdom'), ('tot', '1')]
# 34

# %%
# write your queries
# Consider the country for sport property of the tennis player (NO Country of citizenship). 
# Return the countries with at least one player who was ranked 1 in the tennis ranking  (the result set must be a list of country IRI and label).

# Q41520 wimbledon

# P106('occupation'),
# Q10833314 ('tennis player')
# --P1352 ('ranking')--> ('o', '1')

# GETTING ALL TENNIS PLAYER
# GETTING their ranking
# FILTERING, only who was ranked 1
# getting their countryForSport
# RETURNing distinc countries 
# REMOVED counting
queryString = """

PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
SELECT DISTINCT ?countryForSport ?countryForSportName
WHERE {
   # ?o wdt:P106 wd:Q10833314;
        wdt:P1352 ?ranking;
        wdt:P1532 ?countryForSport.
   # get the label 
   # ?countryForSport sc:name ?countryForSportName.
   OPTIONAL { ?o sc:name ?oName }.
   FILTER (xsd:integer(?ranking) = 1)
}
GROUP BY ?countryForSport ?countryForSportName
LIMIT 100

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('countryForSport', 'http://www.wikidata.org/entity/Q215'), ('countryForSportName', 'Slovenia')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q218'), ('countryForSportName', 'Romania')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q16'), ('countryForSportName', 'Canada')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q38'), ('countryForSportName', 'Italy')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q216923'), ('countryForSportName', 'Chinese Taipei')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q183'), ('countryForSportName', 'Germany')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q83286'), ('countryForSportName', 'Socialist Federal Republic of Yugoslavia')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q34'), ('countryForSportName', 'Sweden')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q31'), ('countryForSportName', 'Belgium')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q403'), ('countryForSportName', 'Serbia')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q155'), ('countryForSportName', 'Brazil')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q212'), ('countryForSportName', 'Ukraine')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q29'), ('countryForSportName', 'Spain')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q148'), ('countryForSportName', "People's Republic of China")]
# [('countryForSport', 'http://www.wikidata.org/entity/Q184'), ('countryForSportName', 'Belarus')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q33'), ('countryForSportName', 'Finland')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q668'), ('countryForSportName', 'India')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q142'), ('countryForSportName', 'France')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q224'), ('countryForSportName', 'Croatia')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q36'), ('countryForSportName', 'Poland')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q213'), ('countryForSportName', 'Czech Republic')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q29999'), ('countryForSportName', 'Kingdom of the Netherlands')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q30'), ('countryForSportName', 'United States of America')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q17'), ('countryForSportName', 'Japan')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q35'), ('countryForSportName', 'Denmark')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q408'), ('countryForSportName', 'Australia')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q33946'), ('countryForSportName', 'Czechoslovakia')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q159'), ('countryForSportName', 'Russia')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q39'), ('countryForSportName', 'Switzerland')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q191'), ('countryForSportName', 'Estonia')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q739'), ('countryForSportName', 'Colombia')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q15180'), ('countryForSportName', 'Soviet Union')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q211'), ('countryForSportName', 'Latvia')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q145'), ('countryForSportName', 'United Kingdom')]
# 34

# %%
# write your queries
# Consider the country for sport property of the tennis player (NO Country of citizenship). 
# Return the countries with at least one player who was ranked 1 in the tennis ranking  (the result set must be a list of country IRI and label).

# Q41520 wimbledon

# P106('occupation'),
# Q10833314 ('tennis player')
# --P1352 ('ranking')--> ('o', '1')

# GETTING ALL TENNIS PLAYER
# GETTING their ranking
# FILTERING, only who was ranked 1
# getting their countryForSport
# RETURNing distinct countries

# checking winner from Italy

queryString = """

PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
SELECT DISTINCT ?o ?oName ?ranking ?countryForSport ?countryForSportName
WHERE {
   # ?o wdt:P106 wd:Q10833314;
        wdt:P1352 ?ranking;
        wdt:P1532 ?countryForSport.
   # get the label 
   # ?countryForSport sc:name ?countryForSportName
   OPTIONAL { ?o sc:name ?oName }.
   FILTER (xsd:integer(?ranking) = 1)
   FILTER (regex(?countryForSportName,"Italy"))
}
LIMIT 100

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('o', 'http://www.wikidata.org/entity/Q95162'), ('oName', 'Roberta Vinci'), ('ranking', '1'), ('countryForSport', 'http://www.wikidata.org/entity/Q38'), ('countryForSportName', 'Italy')]
# [('o', 'http://www.wikidata.org/entity/Q207528'), ('oName', 'Flavia Pennetta'), ('ranking', '1'), ('countryForSport', 'http://www.wikidata.org/entity/Q38'), ('countryForSportName', 'Italy')]
# 2

# %%
# write your queries
# Consider the country for sport property of the tennis player (NO Country of citizenship). 
# Return the countries with at least one player who was ranked 1 in the tennis ranking  (the result set must be a list of country IRI and label).

# Q41520 wimbledon

# P106('occupation'),
# Q10833314 ('tennis player')
# --P1352 ('ranking')--> ('o', '1')

# GETTING ALL TENNIS PLAYER
# GETTING their ranking
# FILTERING, only who was ranked 1
# getting their countryForSport
# RETURNing distinct countries

# checking winner from Italy

# RESULT with ordering

queryString = """

PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
SELECT DISTINCT ?countryForSport ?countryForSportName
WHERE {
   # ?o wdt:P106 wd:Q10833314;
        wdt:P1352 ?ranking;
        wdt:P1532 ?countryForSport.
   # get the label 
   # ?countryForSport sc:name ?countryForSportName.
   OPTIONAL { ?o sc:name ?oName }.
   FILTER (xsd:integer(?ranking) = 1)
}
GROUP BY ?countryForSport ?countryForSportName
ORDER BY ?countryForSportName
LIMIT 100

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('countryForSport', 'http://www.wikidata.org/entity/Q408'), ('countryForSportName', 'Australia')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q184'), ('countryForSportName', 'Belarus')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q31'), ('countryForSportName', 'Belgium')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q155'), ('countryForSportName', 'Brazil')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q16'), ('countryForSportName', 'Canada')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q216923'), ('countryForSportName', 'Chinese Taipei')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q739'), ('countryForSportName', 'Colombia')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q224'), ('countryForSportName', 'Croatia')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q213'), ('countryForSportName', 'Czech Republic')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q33946'), ('countryForSportName', 'Czechoslovakia')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q35'), ('countryForSportName', 'Denmark')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q191'), ('countryForSportName', 'Estonia')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q33'), ('countryForSportName', 'Finland')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q142'), ('countryForSportName', 'France')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q183'), ('countryForSportName', 'Germany')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q668'), ('countryForSportName', 'India')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q38'), ('countryForSportName', 'Italy')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q17'), ('countryForSportName', 'Japan')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q29999'), ('countryForSportName', 'Kingdom of the Netherlands')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q211'), ('countryForSportName', 'Latvia')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q148'), ('countryForSportName', "People's Republic of China")]
# [('countryForSport', 'http://www.wikidata.org/entity/Q36'), ('countryForSportName', 'Poland')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q218'), ('countryForSportName', 'Romania')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q159'), ('countryForSportName', 'Russia')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q403'), ('countryForSportName', 'Serbia')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q215'), ('countryForSportName', 'Slovenia')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q83286'), ('countryForSportName', 'Socialist Federal Republic of Yugoslavia')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q15180'), ('countryForSportName', 'Soviet Union')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q29'), ('countryForSportName', 'Spain')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q34'), ('countryForSportName', 'Sweden')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q39'), ('countryForSportName', 'Switzerland')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q212'), ('countryForSportName', 'Ukraine')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q145'), ('countryForSportName', 'United Kingdom')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q30'), ('countryForSportName', 'United States of America')]
# 34

# %% [markdown]
# ### Final query for this task

# %%
# write your queries
# Consider the country for sport property of the tennis player (NO Country of citizenship). 
# Return the countries with at least one player who was ranked 1 in the tennis ranking  (the result set must be a list of country IRI and label).

# P106('occupation'),
# Q10833314 ('tennis player')
# --P1352 ('ranking')--> ('o', '1')
# --P1532 ('country for sport')

queryString = """

PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
SELECT DISTINCT ?countryForSport ?countryForSportName
WHERE {
   # getting all tennis player
   # ?o wdt:P106 wd:Q10833314;
        wdt:P1352 ?ranking; # their rankings
        wdt:P1532 ?countryForSport. # their country for sport
   
   # get the label 
   # ?countryForSport sc:name ?countryForSportName.
   
   # Filtering player who ranked as first
   FILTER (xsd:integer(?ranking) = 1)
}
GROUP BY ?countryForSport ?countryForSportName
ORDER BY ?countryForSportName
LIMIT 100

"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('countryForSport', 'http://www.wikidata.org/entity/Q408'), ('countryForSportName', 'Australia')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q184'), ('countryForSportName', 'Belarus')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q31'), ('countryForSportName', 'Belgium')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q155'), ('countryForSportName', 'Brazil')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q16'), ('countryForSportName', 'Canada')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q216923'), ('countryForSportName', 'Chinese Taipei')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q739'), ('countryForSportName', 'Colombia')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q224'), ('countryForSportName', 'Croatia')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q213'), ('countryForSportName', 'Czech Republic')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q33946'), ('countryForSportName', 'Czechoslovakia')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q35'), ('countryForSportName', 'Denmark')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q191'), ('countryForSportName', 'Estonia')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q33'), ('countryForSportName', 'Finland')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q142'), ('countryForSportName', 'France')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q183'), ('countryForSportName', 'Germany')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q668'), ('countryForSportName', 'India')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q38'), ('countryForSportName', 'Italy')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q17'), ('countryForSportName', 'Japan')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q29999'), ('countryForSportName', 'Kingdom of the Netherlands')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q211'), ('countryForSportName', 'Latvia')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q148'), ('countryForSportName', "People's Republic of China")]
# [('countryForSport', 'http://www.wikidata.org/entity/Q36'), ('countryForSportName', 'Poland')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q218'), ('countryForSportName', 'Romania')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q159'), ('countryForSportName', 'Russia')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q403'), ('countryForSportName', 'Serbia')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q215'), ('countryForSportName', 'Slovenia')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q83286'), ('countryForSportName', 'Socialist Federal Republic of Yugoslavia')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q15180'), ('countryForSportName', 'Soviet Union')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q29'), ('countryForSportName', 'Spain')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q34'), ('countryForSportName', 'Sweden')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q39'), ('countryForSportName', 'Switzerland')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q212'), ('countryForSportName', 'Ukraine')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q145'), ('countryForSportName', 'United Kingdom')]
# [('countryForSport', 'http://www.wikidata.org/entity/Q30'), ('countryForSportName', 'United States of America')]
# 34

# %% [markdown]
# ## ALERT! DO NOT RUN the following queries:
# The following queries are my old and BAD queries in TASK 6 (I have commented them above). Even though they did not help me find what I was looking for, the professor asked me to put them anyway in the notebook.
# Please do not run them as they are very computationally heavy, and they may break the server.

# %% [markdown]
# ### All useless queries to find dob

# %%
# Consider the tennis players born after 1975, return who won more Grand Slams and cut the result to the top-10 (the result set must be a list of triples player IRI, label and #victories).
# Q1426 = Roger Federer
# wdt:P1344 (participant in)
# wdt:P2522 (victory)
#[('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('o', 'http://www.wikidata.org/entity/P569'), ('oName', 'date of birth')]

# 1) getting winners dob 
queryString = """

PREFIX xsd:  <http://www.w3.org/2001/XMLSchema#>
SELECT DISTINCT ?s ?sName ?pName ?o ?oName
WHERE {
   # ?s ?p ?o.
   # ?s sc:name ?sName.
   # ?p sc:name ?pName.
   # ?o sc:name ?oName.
   #it never returns the result if un-comment the filter
   #FILTER (?o > "1975"^^xsd:gYear)
}
LIMIT 10
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('s', 'http://www.wikidata.org/entity/Q95452024'), ('sName', 'Template:Vice Presidents of the Maldives'), ('pName', 'template has topic'), ('o', 'http://www.wikidata.org/entity/Q10999435'), ('oName', 'Vice President of the Maldives')]
# [('s', 'http://www.wikidata.org/entity/Q25752552'), ('sName', 'Template:2001 in Europe'), ('pName', 'template has topic'), ('o', 'http://www.wikidata.org/entity/Q17111750'), ('oName', '2001 in Europe')]
# [('s', 'http://www.wikidata.org/entity/Q6675314'), ('sName', 'Template:Alcest'), ('pName', 'template has topic'), ('o', 'http://www.wikidata.org/entity/Q1517060'), ('oName', 'Alcest')]
# [('s', 'http://www.wikidata.org/entity/Q22785857'), ('sName', 'Template:2006 in Europe'), ('pName', 'template has topic'), ('o', 'http://www.wikidata.org/entity/Q17111782'), ('oName', '2006 in Europe')]
# [('s', 'http://www.wikidata.org/entity/Q85816744'), ('sName', 'Yodli'), ('pName', 'represents'), ('o', 'http://www.wikidata.org/entity/Q1053559'), ('oName', '2020 Winter Youth Olympics')]
# [('s', 'http://www.wikidata.org/entity/Q1064606'), ('sName', 'President of the Maldives'), ('pName', 'substitute/deputy/replacement of office/officeholder'), ('o', 'http://www.wikidata.org/entity/Q10999435'), ('oName', 'Vice President of the Maldives')]
# [('s', 'http://www.wikidata.org/entity/Q10275776'), ('sName', 'Estação Ferroviária de Mafra'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q18483474'), ('sName', 'Telhada halt'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q8202323'), ('sName', 'Alcainça-Moinhos halt'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q8202353'), ('sName', 'Bicanho Halt'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# 10

# %%
# Consider the tennis players born after 1975, return who won more Grand Slams and cut the result to the top-10 (the result set must be a list of triples player IRI, label and #victories).
# Q1426 = Roger Federer
# wdt:P1344 (participant in)
# wdt:P2522 (victory)
#[('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('o', 'http://www.wikidata.org/entity/P569'), ('oName', 'date of birth')]

# 1) getting winners dob 
queryString = """

SELECT DISTINCT ?s ?sName ?p ?pName ?o ?oName
WHERE {
   # ?s ?p ?o.
   # ?s sc:name ?sName.
   # ?p sc:name ?pName.
   # ?o sc:name ?oName.
   FILTER (REGEX(?oName, "1975.*"))
   FILTER (?p != wdt:P155 && ?p != wdt:P301)
}
LIMIT 10
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('s', 'http://www.wikidata.org/entity/Q4574296'), ('sName', '1970s in Hong Kong'), ('p', 'http://www.wikidata.org/prop/direct/P527'), ('pName', 'has part'), ('o', 'http://www.wikidata.org/entity/Q15930131'), ('oName', '1975 in Hong Kong')]
# [('s', 'http://www.wikidata.org/entity/Q19568414'), ('sName', '1974 in Iran'), ('p', 'http://www.wikidata.org/prop/direct/P156'), ('pName', 'followed by'), ('o', 'http://www.wikidata.org/entity/Q20987712'), ('oName', '1975 in Iran')]
# [('s', 'http://www.wikidata.org/entity/Q19568417'), ('sName', '1974 in Kuwait'), ('p', 'http://www.wikidata.org/prop/direct/P156'), ('pName', 'followed by'), ('o', 'http://www.wikidata.org/entity/Q19568426'), ('oName', '1975 in Kuwait')]
# [('s', 'http://www.wikidata.org/entity/Q30731465'), ('sName', 'Category:1975 in Yugoslavian sport'), ('p', 'http://www.wikidata.org/prop/direct/P971'), ('pName', 'category combines topics'), ('o', 'http://www.wikidata.org/entity/Q1074111'), ('oName', '1975 in sports')]
# [('s', 'http://www.wikidata.org/entity/Q765955'), ('sName', '1974 in sports'), ('p', 'http://www.wikidata.org/prop/direct/P156'), ('pName', 'followed by'), ('o', 'http://www.wikidata.org/entity/Q1074111'), ('oName', '1975 in sports')]
# [('s', 'http://www.wikidata.org/entity/Q12780106'), ('sName', 'Category:1975 in Norwegian sport'), ('p', 'http://www.wikidata.org/prop/direct/P971'), ('pName', 'category combines topics'), ('o', 'http://www.wikidata.org/entity/Q1074111'), ('oName', '1975 in sports')]
# [('s', 'http://www.wikidata.org/entity/Q52194164'), ('sName', '1974 in Tunisia'), ('p', 'http://www.wikidata.org/prop/direct/P156'), ('pName', 'followed by'), ('o', 'http://www.wikidata.org/entity/Q52194165'), ('oName', '1975 in Tunisia')]
# [('s', 'http://www.wikidata.org/entity/Q4576321'), ('sName', '1974 in Denmark'), ('p', 'http://www.wikidata.org/prop/direct/P156'), ('pName', 'followed by'), ('o', 'http://www.wikidata.org/entity/Q4576876'), ('oName', '1975 in Denmark')]
# [('s', 'http://www.wikidata.org/entity/Q19839683'), ('sName', '1974 in Taiwan'), ('p', 'http://www.wikidata.org/prop/direct/P156'), ('pName', 'followed by'), ('o', 'http://www.wikidata.org/entity/Q4576919'), ('oName', '1975 in Taiwan')]
# [('s', 'http://www.wikidata.org/entity/Q8160342'), ('sName', 'Category:1975 in Swedish sport'), ('p', 'http://www.wikidata.org/prop/direct/P971'), ('pName', 'category combines topics'), ('o', 'http://www.wikidata.org/entity/Q1074111'), ('oName', '1975 in sports')]
# 10

# %%
# Consider the tennis players born after 1975, return who won more Grand Slams and cut the result to the top-10 (the result set must be a list of triples player IRI, label and #victories).
# Q1426 = Roger Federer
# wdt:P1344 (participant in)
# wdt:P2522 (victory)
#[('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('o', 'http://www.wikidata.org/entity/P569'), ('oName', 'date of birth')]

# 1) getting winners dob 
queryString = """

SELECT DISTINCT ?s ?sName ?p ?pName ?o ?oName
WHERE {
   # ?s ?p ?o.
   # ?s sc:name ?sName.
   # ?p sc:name ?pName.
   # ?o sc:name ?oName.
   
   #it never returns the result if un-comment the filter
   FILTER (REGEX(?oName, "1981-08-08.*"))
   FILTER (?p NOT IN (wdt:P155,wdt:P301))
}
LIMIT 10
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('s', 'http://www.wikidata.org/entity/Q10275776'), ('sName', 'Estação Ferroviária de Mafra'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q11235194'), ('sName', 'Tokyo Solamachi'), ('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q11497641'), ('oName', 'Oshiage')]
# [('s', 'http://www.wikidata.org/entity/Q15628796'), ('sName', 'Pedro Ponce de Cabrera'), ('p', 'http://www.wikidata.org/prop/direct/P119'), ('pName', 'place of burial'), ('o', 'http://www.wikidata.org/entity/Q16608610'), ('oName', 'Monastery of Santa María de Nogales')]
# [('s', 'http://www.wikidata.org/entity/Q18483474'), ('sName', 'Telhada halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q18531652'), ('sName', 'William Walker'), ('p', 'http://www.wikidata.org/prop/direct/P1343'), ('pName', 'described by source'), ('o', 'http://www.wikidata.org/entity/Q17037575'), ('oName', 'Oxford Biography Index')]
# [('s', 'http://www.wikidata.org/entity/Q4829629'), ('sName', 'Awa-Ōmiya Station'), ('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q1350904'), ('oName', 'Itano')]
# [('s', 'http://www.wikidata.org/entity/Q7371392'), ('sName', 'Route 1'), ('p', 'http://www.wikidata.org/prop/direct/P126'), ('pName', 'maintained by'), ('o', 'http://www.wikidata.org/entity/Q11415304'), ('oName', 'Nagoya Expressway Public Corporation')]
# [('s', 'http://www.wikidata.org/entity/Q8134074'), ('sName', 'Sumida Aquarium'), ('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q11497641'), ('oName', 'Oshiage')]
# [('s', 'http://www.wikidata.org/entity/Q8146191'), ('sName', 'Nanga Pinoh'), ('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q14162'), ('oName', 'Melawi')]
# [('s', 'http://www.wikidata.org/entity/Q8167413'), ('sName', 'Guguak VIII Koto'), ('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q12403132'), ('oName', 'Guguak')]
# 10

# %%
# Consider the tennis players born after 1975, return who won more Grand Slams and cut the result to the top-10 (the result set must be a list of triples player IRI, label and #victories).
# Q1426 = Roger Federer
# wdt:P1344 (participant in)
# wdt:P2522 (victory)
#[('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('o', 'http://www.wikidata.org/entity/P569'), ('oName', 'date of birth')]

# 1) getting winners dob 
queryString = """

SELECT DISTINCT ?s ?sName ?p ?pName ?o ?oName
WHERE {
   # ?s ?p ?o.
   # ?s sc:name ?sName.
   # ?p sc:name ?pName.
   # ?o sc:name ?oName.
   
   #it never returns the result if un-comment the filter
   FILTER (REGEX(?oName, "1981-08-0.*"))
}
LIMIT 1
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('s', 'http://www.wikidata.org/entity/Q95452024'), ('sName', 'Template:Vice Presidents of the Maldives'), ('p', 'http://www.wikidata.org/prop/direct/P1423'), ('pName', 'template has topic'), ('o', 'http://www.wikidata.org/entity/Q10999435'), ('oName', 'Vice President of the Maldives')]
# 1

# %%
# Consider the tennis players born after 1975, return who won more Grand Slams and cut the result to the top-10 (the result set must be a list of triples player IRI, label and #victories).
# Q1426 = Roger Federer
# wdt:P1344 (participant in)
# wdt:P2522 (victory)
#[('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('o', 'http://www.wikidata.org/entity/P569'), ('oName', 'date of birth')]

# 1) getting winners dob 
queryString = """

SELECT DISTINCT ?s ?sName ?p ?pName ?o ?oName
WHERE {
   # ?s ?p ?o.
   # ?s sc:name ?sName.
   # ?p sc:name ?pName.
   # ?o sc:name ?oName.
   FILTER (REGEX(?oName, "1981.*"))
}
LIMIT 10
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('s', 'http://www.wikidata.org/entity/Q8165395'), ('sName', 'Category:1982 elections in South America'), ('p', 'http://www.wikidata.org/prop/direct/P155'), ('pName', 'follows'), ('o', 'http://www.wikidata.org/entity/Q16772598'), ('oName', 'Category:1981 elections in South America')]
# [('s', 'http://www.wikidata.org/entity/Q15120431'), ('sName', 'Category:1982 in go'), ('p', 'http://www.wikidata.org/prop/direct/P155'), ('pName', 'follows'), ('o', 'http://www.wikidata.org/entity/Q15120313'), ('oName', 'Category:1981 in go')]
# [('s', 'http://www.wikidata.org/entity/Q8165681'), ('sName', 'Category:1982 in New Zealand sport'), ('p', 'http://www.wikidata.org/prop/direct/P155'), ('pName', 'follows'), ('o', 'http://www.wikidata.org/entity/Q11721574'), ('oName', 'Category:1981 in New Zealand sport')]
# [('s', 'http://www.wikidata.org/entity/Q52179909'), ('sName', '1982 in Finland'), ('p', 'http://www.wikidata.org/prop/direct/P155'), ('pName', 'follows'), ('o', 'http://www.wikidata.org/entity/Q62053918'), ('oName', '1981 in Finland')]
# [('s', 'http://www.wikidata.org/entity/Q2176147'), ('sName', '1982 in radio'), ('p', 'http://www.wikidata.org/prop/direct/P155'), ('pName', 'follows'), ('o', 'http://www.wikidata.org/entity/Q18027558'), ('oName', '1981 in radio')]
# [('s', 'http://www.wikidata.org/entity/Q4580698'), ('sName', '1982 in Bangladesh'), ('p', 'http://www.wikidata.org/prop/direct/P155'), ('pName', 'follows'), ('o', 'http://www.wikidata.org/entity/Q4580079'), ('oName', '1981 in Bangladesh')]
# [('s', 'http://www.wikidata.org/entity/Q19568493'), ('sName', '1982 in Iran'), ('p', 'http://www.wikidata.org/prop/direct/P155'), ('pName', 'follows'), ('o', 'http://www.wikidata.org/entity/Q19568484'), ('oName', '1981 in Iran')]
# [('s', 'http://www.wikidata.org/entity/Q8163328'), ('sName', 'Category:1980 elections in South America'), ('p', 'http://www.wikidata.org/prop/direct/P156'), ('pName', 'followed by'), ('o', 'http://www.wikidata.org/entity/Q16772598'), ('oName', 'Category:1981 elections in South America')]
# [('s', 'http://www.wikidata.org/entity/Q8163633'), ('sName', 'Category:1980 in New Zealand sport'), ('p', 'http://www.wikidata.org/prop/direct/P156'), ('pName', 'followed by'), ('o', 'http://www.wikidata.org/entity/Q11721574'), ('oName', 'Category:1981 in New Zealand sport')]
# [('s', 'http://www.wikidata.org/entity/Q2176145'), ('sName', '1980 in radio'), ('p', 'http://www.wikidata.org/prop/direct/P156'), ('pName', 'followed by'), ('o', 'http://www.wikidata.org/entity/Q18027558'), ('oName', '1981 in radio')]
# 10

# %%
# Consider the tennis players born after 1975, return who won more Grand Slams and cut the result to the top-10 (the result set must be a list of triples player IRI, label and #victories).
# Q1426 = Roger Federer
# wdt:P1344 (participant in)
# wdt:P2522 (victory)
#[('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('o', 'http://www.wikidata.org/entity/P569'), ('oName', 'date of birth')]

# 1) getting winners dob 
queryString = """

SELECT DISTINCT ?s ?sName ?p ?pName ?o ?oName
WHERE {
   # ?s ?p ?o.
   # ?s sc:name ?sName.
   # ?p sc:name ?pName.
   # ?o sc:name ?oName.
   FILTER (?oName = "1981")
}
LIMIT 10
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# Empty

# %%
# Consider the tennis players born after 1975, return who won more Grand Slams and cut the result to the top-10 (the result set must be a list of triples player IRI, label and #victories).
# Q1426 = Roger Federer
# wdt:P1344 (participant in)
# wdt:P2522 (victory)
#[('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('o', 'http://www.wikidata.org/entity/P569'), ('oName', 'date of birth')]
# 1) getting winners dob 
queryString = """

SELECT DISTINCT ?s ?sName ?p ?pName ?o ?oName
WHERE {
   # ?s ?p ?o.
   # ?s sc:name ?sName.
   # ?p sc:name ?pName.
   # ?o sc:name ?oName.
   FILTER (?oName = "1981-08")
}
LIMIT 10
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# Empty

# %%
# Consider the tennis players born after 1975, return who won more Grand Slams and cut the result to the top-10 (the result set must be a list of triples player IRI, label and #victories).
# Q1426 = Roger Federer
# wdt:P1344 (participant in)
# wdt:P2522 (victory)
#[('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('o', 'http://www.wikidata.org/entity/P569'), ('oName', 'date of birth')]
# 1) getting winners dob 
queryString = """

SELECT DISTINCT ?s ?sName ?p ?pName ?o ?oName
WHERE {
   # ?s ?p ?o.
   # ?s sc:name ?sName.
   # ?p sc:name ?pName.
   # ?o sc:name ?oName.
   FILTER (?oName = "1981-08-08")
}
LIMIT 10
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# Empty

# %%
# Consider the tennis players born after 1975, return who won more Grand Slams and cut the result to the top-10 (the result set must be a list of triples player IRI, label and #victories).
# Q1426 = Roger Federer
# wdt:P1344 (participant in)
# wdt:P2522 (victory)
#[('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('o', 'http://www.wikidata.org/entity/P569'), ('oName', 'date of birth')]
# 1) getting winners dob 
queryString = """

SELECT DISTINCT ?s ?sName ?p ?pName ?o ?oName
WHERE {
   # ?s ?p ?o.
   # ?s sc:name ?sName.
   # ?p sc:name ?pName.
   # ?o sc:name ?oName.
   FILTER (REGEX(?oName,"1987-.*"))
}
LIMIT 10
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('s', 'http://www.wikidata.org/entity/Q17027610'), ('sName', 'Remembering Christmas'), ('p', 'http://www.wikidata.org/prop/direct/P155'), ('pName', 'follows'), ('o', 'http://www.wikidata.org/entity/Q16953722'), ('oName', 'The Best of David Benoit 1987-1995')]
# [('s', 'http://www.wikidata.org/entity/Q16466348'), ('sName', 'Shaken Not Stirred'), ('p', 'http://www.wikidata.org/prop/direct/P156'), ('pName', 'followed by'), ('o', 'http://www.wikidata.org/entity/Q16953722'), ('oName', 'The Best of David Benoit 1987-1995')]
# [('s', 'http://www.wikidata.org/entity/Q34757794'), ('sName', 'Child labor and musculoskeletal disorders: the Pelotas (Brazil) epidemiological survey.'), ('p', 'http://www.wikidata.org/prop/direct/P2860'), ('pName', 'cites work'), ('o', 'http://www.wikidata.org/entity/Q24169399'), ('oName', 'Work-related injuries to Massachusetts teens, 1987-1990')]
# [('s', 'http://www.wikidata.org/entity/Q23910866'), ('sName', "Teen workers' exposures to occupational hazards and use of personal protective equipment"), ('p', 'http://www.wikidata.org/prop/direct/P2860'), ('pName', 'cites work'), ('o', 'http://www.wikidata.org/entity/Q24169399'), ('oName', 'Work-related injuries to Massachusetts teens, 1987-1990')]
# [('s', 'http://www.wikidata.org/entity/Q28384893'), ('sName', 'Labor and Related Injuries among Schoolchildren in Palestine: Findings from the National Study of Palestinian Schoolchildren (HBSC-WBG2006)'), ('p', 'http://www.wikidata.org/prop/direct/P2860'), ('pName', 'cites work'), ('o', 'http://www.wikidata.org/entity/Q24169399'), ('oName', 'Work-related injuries to Massachusetts teens, 1987-1990')]
# [('s', 'http://www.wikidata.org/entity/Q28396037'), ('sName', 'An ecological study of regional variation in work injuries among young workers.'), ('p', 'http://www.wikidata.org/prop/direct/P2860'), ('pName', 'cites work'), ('o', 'http://www.wikidata.org/entity/Q24169399'), ('oName', 'Work-related injuries to Massachusetts teens, 1987-1990')]
# [('s', 'http://www.wikidata.org/entity/Q45833345'), ('sName', 'Child labor and protecting young workers around the world. An introduction to this issue.'), ('p', 'http://www.wikidata.org/prop/direct/P2860'), ('pName', 'cites work'), ('o', 'http://www.wikidata.org/entity/Q24169399'), ('oName', 'Work-related injuries to Massachusetts teens, 1987-1990')]
# [('s', 'http://www.wikidata.org/entity/Q38366777'), ('sName', 'Epidemiology of work-related traumatic brain injury: a systematic review.'), ('p', 'http://www.wikidata.org/prop/direct/P2860'), ('pName', 'cites work'), ('o', 'http://www.wikidata.org/entity/Q24169399'), ('oName', 'Work-related injuries to Massachusetts teens, 1987-1990')]
# [('s', 'http://www.wikidata.org/entity/Q28393715'), ('sName', "Age related differences in work injuries and permanent impairment: a comparison of workers' compensation claims among adolescents, young adults, and adults"), ('p', 'http://www.wikidata.org/prop/direct/P2860'), ('pName', 'cites work'), ('o', 'http://www.wikidata.org/entity/Q24169399'), ('oName', 'Work-related injuries to Massachusetts teens, 1987-1990')]
# [('s', 'http://www.wikidata.org/entity/Q39651534'), ('sName', 'Occupational accidents among middle and high school students of the state of São Paulo, Brazil.'), ('p', 'http://www.wikidata.org/prop/direct/P2860'), ('pName', 'cites work'), ('o', 'http://www.wikidata.org/entity/Q24169399'), ('oName', 'Work-related injuries to Massachusetts teens, 1987-1990')]
# 10

# %%
# Consider the tennis players born after 1975, return who won more Grand Slams and cut the result to the top-10 (the result set must be a list of triples player IRI, label and #victories).
# Q1426 = Roger Federer
# wdt:P1344 (participant in)
# wdt:P2522 (victory)
#[('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('o', 'http://www.wikidata.org/entity/P569'), ('oName', 'date of birth')]
# 1) getting winners dob 
queryString = """

SELECT DISTINCT ?s ?sName ?p ?pName ?o ?oName
WHERE {
   # ?s ?p ?o.
   # ?s sc:name ?sName.
   # ?p sc:name ?pName.
   # ?o sc:name ?oName.
   
   
   #it never returns the result if un-comment the filter
   FILTER (REGEX(?oName,"1987-05.*"))
}
LIMIT 10
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('s', 'http://www.wikidata.org/entity/Q95452024'), ('sName', 'Template:Vice Presidents of the Maldives'), ('p', 'http://www.wikidata.org/prop/direct/P1423'), ('pName', 'template has topic'), ('o', 'http://www.wikidata.org/entity/Q10999435'), ('oName', 'Vice President of the Maldives')]
# [('s', 'http://www.wikidata.org/entity/Q25752552'), ('sName', 'Template:2001 in Europe'), ('p', 'http://www.wikidata.org/prop/direct/P1423'), ('pName', 'template has topic'), ('o', 'http://www.wikidata.org/entity/Q17111750'), ('oName', '2001 in Europe')]
# [('s', 'http://www.wikidata.org/entity/Q6675314'), ('sName', 'Template:Alcest'), ('p', 'http://www.wikidata.org/prop/direct/P1423'), ('pName', 'template has topic'), ('o', 'http://www.wikidata.org/entity/Q1517060'), ('oName', 'Alcest')]
# [('s', 'http://www.wikidata.org/entity/Q22785857'), ('sName', 'Template:2006 in Europe'), ('p', 'http://www.wikidata.org/prop/direct/P1423'), ('pName', 'template has topic'), ('o', 'http://www.wikidata.org/entity/Q17111782'), ('oName', '2006 in Europe')]
# [('s', 'http://www.wikidata.org/entity/Q85816744'), ('sName', 'Yodli'), ('p', 'http://www.wikidata.org/prop/direct/P1268'), ('pName', 'represents'), ('o', 'http://www.wikidata.org/entity/Q1053559'), ('oName', '2020 Winter Youth Olympics')]
# [('s', 'http://www.wikidata.org/entity/Q1064606'), ('sName', 'President of the Maldives'), ('p', 'http://www.wikidata.org/prop/direct/P2098'), ('pName', 'substitute/deputy/replacement of office/officeholder'), ('o', 'http://www.wikidata.org/entity/Q10999435'), ('oName', 'Vice President of the Maldives')]
# [('s', 'http://www.wikidata.org/entity/Q10275776'), ('sName', 'Estação Ferroviária de Mafra'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q18483474'), ('sName', 'Telhada halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q8202323'), ('sName', 'Alcainça-Moinhos halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q8202353'), ('sName', 'Bicanho Halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# 10

# %%
# Consider the tennis players born after 1975, return who won more Grand Slams and cut the result to the top-10 (the result set must be a list of triples player IRI, label and #victories).
# Q1426 = Roger Federer
# wdt:P1344 (participant in)
# wdt:P2522 (victory)
#[('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('o', 'http://www.wikidata.org/entity/P569'), ('oName', 'date of birth')]
# 1) getting winners dob 

queryString = """

SELECT DISTINCT ?s ?sName ?p ?pName ?o ?oName
WHERE {
   # ?s ?p ?o.
   # ?s sc:name ?sName.
   # ?p sc:name ?pName.
   # ?o sc:name ?oName.
   
   FILTER (REGEX(?oName,"May 1987"))
}
LIMIT 10
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('s', 'http://www.wikidata.org/entity/Q9615411'), ('sName', 'Category:May 1987 events'), ('p', 'http://www.wikidata.org/prop/direct/P301'), ('pName', "category's main topic"), ('o', 'http://www.wikidata.org/entity/Q13072296'), ('oName', 'May 1987')]
# [('s', 'http://www.wikidata.org/entity/Q69297253'), ('sName', 'May 4, 1987'), ('p', 'http://www.wikidata.org/prop/direct/P361'), ('pName', 'part of'), ('o', 'http://www.wikidata.org/entity/Q13072296'), ('oName', 'May 1987')]
# [('s', 'http://www.wikidata.org/entity/Q69297267'), ('sName', 'May 16, 1987'), ('p', 'http://www.wikidata.org/prop/direct/P361'), ('pName', 'part of'), ('o', 'http://www.wikidata.org/entity/Q13072296'), ('oName', 'May 1987')]
# [('s', 'http://www.wikidata.org/entity/Q69297272'), ('sName', 'May 20, 1987'), ('p', 'http://www.wikidata.org/prop/direct/P361'), ('pName', 'part of'), ('o', 'http://www.wikidata.org/entity/Q13072296'), ('oName', 'May 1987')]
# [('s', 'http://www.wikidata.org/entity/Q69297268'), ('sName', 'May 17, 1987'), ('p', 'http://www.wikidata.org/prop/direct/P361'), ('pName', 'part of'), ('o', 'http://www.wikidata.org/entity/Q13072296'), ('oName', 'May 1987')]
# [('s', 'http://www.wikidata.org/entity/Q69297273'), ('sName', 'May 21, 1987'), ('p', 'http://www.wikidata.org/prop/direct/P361'), ('pName', 'part of'), ('o', 'http://www.wikidata.org/entity/Q13072296'), ('oName', 'May 1987')]
# [('s', 'http://www.wikidata.org/entity/Q69297274'), ('sName', 'May 22, 1987'), ('p', 'http://www.wikidata.org/prop/direct/P361'), ('pName', 'part of'), ('o', 'http://www.wikidata.org/entity/Q13072296'), ('oName', 'May 1987')]
# [('s', 'http://www.wikidata.org/entity/Q69297256'), ('sName', 'May 7, 1987'), ('p', 'http://www.wikidata.org/prop/direct/P361'), ('pName', 'part of'), ('o', 'http://www.wikidata.org/entity/Q13072296'), ('oName', 'May 1987')]
# [('s', 'http://www.wikidata.org/entity/Q69297264'), ('sName', 'May 14, 1987'), ('p', 'http://www.wikidata.org/prop/direct/P361'), ('pName', 'part of'), ('o', 'http://www.wikidata.org/entity/Q13072296'), ('oName', 'May 1987')]
# [('s', 'http://www.wikidata.org/entity/Q69297261'), ('sName', 'May 11, 1987'), ('p', 'http://www.wikidata.org/prop/direct/P361'), ('pName', 'part of'), ('o', 'http://www.wikidata.org/entity/Q13072296'), ('oName', 'May 1987')]
# 10

# %%
# Consider the tennis players born after 1975, return who won more Grand Slams and cut the result to the top-10 (the result set must be a list of triples player IRI, label and #victories).
# Q1426 = Roger Federer
# wdt:P1344 (participant in)
# wdt:P2522 (victory)
#[('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('o', 'http://www.wikidata.org/entity/P569'), ('oName', 'date of birth')]
# 1) getting winners dob 

queryString = """

SELECT DISTINCT ?s ?sName ?p ?pName ?o ?oName
WHERE {
   # ?s ?p ?o.
   # ?s sc:name ?sName.
   # ?p sc:name ?pName.
   # ?o sc:name ?oName.
   
   
   #it never returns the result if un-comment the filter
   FILTER (REGEX(?oName,"May 22, 1987"))
}
LIMIT 10
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('s', 'http://www.wikidata.org/entity/Q95452024'), ('sName', 'Template:Vice Presidents of the Maldives'), ('p', 'http://www.wikidata.org/prop/direct/P1423'), ('pName', 'template has topic'), ('o', 'http://www.wikidata.org/entity/Q10999435'), ('oName', 'Vice President of the Maldives')]
# [('s', 'http://www.wikidata.org/entity/Q25752552'), ('sName', 'Template:2001 in Europe'), ('p', 'http://www.wikidata.org/prop/direct/P1423'), ('pName', 'template has topic'), ('o', 'http://www.wikidata.org/entity/Q17111750'), ('oName', '2001 in Europe')]
# [('s', 'http://www.wikidata.org/entity/Q6675314'), ('sName', 'Template:Alcest'), ('p', 'http://www.wikidata.org/prop/direct/P1423'), ('pName', 'template has topic'), ('o', 'http://www.wikidata.org/entity/Q1517060'), ('oName', 'Alcest')]
# [('s', 'http://www.wikidata.org/entity/Q22785857'), ('sName', 'Template:2006 in Europe'), ('p', 'http://www.wikidata.org/prop/direct/P1423'), ('pName', 'template has topic'), ('o', 'http://www.wikidata.org/entity/Q17111782'), ('oName', '2006 in Europe')]
# [('s', 'http://www.wikidata.org/entity/Q85816744'), ('sName', 'Yodli'), ('p', 'http://www.wikidata.org/prop/direct/P1268'), ('pName', 'represents'), ('o', 'http://www.wikidata.org/entity/Q1053559'), ('oName', '2020 Winter Youth Olympics')]
# [('s', 'http://www.wikidata.org/entity/Q1064606'), ('sName', 'President of the Maldives'), ('p', 'http://www.wikidata.org/prop/direct/P2098'), ('pName', 'substitute/deputy/replacement of office/officeholder'), ('o', 'http://www.wikidata.org/entity/Q10999435'), ('oName', 'Vice President of the Maldives')]
# [('s', 'http://www.wikidata.org/entity/Q10275776'), ('sName', 'Estação Ferroviária de Mafra'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q18483474'), ('sName', 'Telhada halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q8202323'), ('sName', 'Alcainça-Moinhos halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q8202353'), ('sName', 'Bicanho Halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# 10

# %%
# Consider the tennis players born after 1975, return who won more Grand Slams and cut the result to the top-10 (the result set must be a list of triples player IRI, label and #victories).
# Q1426 = Roger Federer
# wdt:P1344 (participant in)
# wdt:P2522 (victory)
#[('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('o', 'http://www.wikidata.org/entity/P569'), ('oName', 'date of birth')]
# 1) getting winners dob 

queryString = """

SELECT DISTINCT ?s ?sName ?p ?pName ?o ?oName
WHERE {
   # ?s ?p ?o.
   # ?s sc:name ?sName.
   # ?p sc:name ?pName.
   # ?o sc:name ?oName.
   
   # SOMETIMES WORKS, sometimes doesn't return any result
   FILTER (REGEX(?pName,"[B|b]irth*"))
   #FILTER (?p not in (wdt:P19))
}
LIMIT 20
"""

print("Results")
x=run_query(queryString)

# %%
# Consider the tennis players born after 1975, return who won more Grand Slams and cut the result to the top-10 (the result set must be a list of triples player IRI, label and #victories).
# Q1426 = Roger Federer
# wdt:P1344 (participant in)
# wdt:P2522 (victory)
#[('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('o', 'http://www.wikidata.org/entity/P569'), ('oName', 'date of birth')]
# 1) getting winners dob 

queryString = """

SELECT DISTINCT ?s ?sName ?p ?pName ?o ?oName
WHERE {
   # ?s ?p ?o.
   # ?s sc:name ?sName.
   # ?p sc:name ?pName.
   # ?o sc:name ?oName.
   
   #it never returns the result if un-comment the filter
   FILTER (REGEX(?pName,"[B|b]irth*"))
   FILTER (?p not in (wdt:P19))
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('s', 'http://www.wikidata.org/entity/Q10275776'), ('sName', 'Estação Ferroviária de Mafra'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q11235194'), ('sName', 'Tokyo Solamachi'), ('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q11497641'), ('oName', 'Oshiage')]
# [('s', 'http://www.wikidata.org/entity/Q15628796'), ('sName', 'Pedro Ponce de Cabrera'), ('p', 'http://www.wikidata.org/prop/direct/P119'), ('pName', 'place of burial'), ('o', 'http://www.wikidata.org/entity/Q16608610'), ('oName', 'Monastery of Santa María de Nogales')]
# [('s', 'http://www.wikidata.org/entity/Q18483474'), ('sName', 'Telhada halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q18531652'), ('sName', 'William Walker'), ('p', 'http://www.wikidata.org/prop/direct/P1343'), ('pName', 'described by source'), ('o', 'http://www.wikidata.org/entity/Q17037575'), ('oName', 'Oxford Biography Index')]
# [('s', 'http://www.wikidata.org/entity/Q4829629'), ('sName', 'Awa-Ōmiya Station'), ('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q1350904'), ('oName', 'Itano')]
# [('s', 'http://www.wikidata.org/entity/Q7371392'), ('sName', 'Route 1'), ('p', 'http://www.wikidata.org/prop/direct/P126'), ('pName', 'maintained by'), ('o', 'http://www.wikidata.org/entity/Q11415304'), ('oName', 'Nagoya Expressway Public Corporation')]
# [('s', 'http://www.wikidata.org/entity/Q8134074'), ('sName', 'Sumida Aquarium'), ('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q11497641'), ('oName', 'Oshiage')]
# [('s', 'http://www.wikidata.org/entity/Q8146191'), ('sName', 'Nanga Pinoh'), ('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q14162'), ('oName', 'Melawi')]
# [('s', 'http://www.wikidata.org/entity/Q8167413'), ('sName', 'Guguak VIII Koto'), ('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q12403132'), ('oName', 'Guguak')]
# [('s', 'http://www.wikidata.org/entity/Q8183600'), ('sName', 'Agrostroj Pelhřimov'), ('p', 'http://www.wikidata.org/prop/direct/P127'), ('pName', 'owned by'), ('o', 'http://www.wikidata.org/entity/Q100343342'), ('oName', 'Lubomír Stoklásek')]
# [('s', 'http://www.wikidata.org/entity/Q8183671'), ('sName', 'Aarão de Lacerda'), ('p', 'http://www.wikidata.org/prop/direct/P108'), ('pName', 'employer'), ('o', 'http://www.wikidata.org/entity/Q10279508'), ('oName', 'Faculdade de Letras da Universidade de Coimbra')]
# [('s', 'http://www.wikidata.org/entity/Q8183671'), ('sName', 'Aarão de Lacerda'), ('p', 'http://www.wikidata.org/prop/direct/P108'), ('pName', 'employer'), ('o', 'http://www.wikidata.org/entity/Q10279509'), ('oName', 'Faculty of Arts and Humanities of the University of Porto')]
# [('s', 'http://www.wikidata.org/entity/Q8190594'), ('sName', 'Awa-Kawabata Station'), ('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q1350904'), ('oName', 'Itano')]
# [('s', 'http://www.wikidata.org/entity/Q8190673'), ('sName', 'Itano Station'), ('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q1350904'), ('oName', 'Itano')]
# [('s', 'http://www.wikidata.org/entity/Q8190939'), ('sName', 'Calaf-Salavinera Airport'), ('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q15967'), ('oName', 'Sant Pere Sallavinera')]
# [('s', 'http://www.wikidata.org/entity/Q8194022'), ('sName', 'Tomonoura'), ('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q17238551'), ('oName', 'Tomo')]
# [('s', 'http://www.wikidata.org/entity/Q8195084'), ('sName', 'mahjong tile'), ('p', 'http://www.wikidata.org/prop/direct/P1269'), ('pName', 'facet of'), ('o', 'http://www.wikidata.org/entity/Q12263'), ('oName', 'mahjong')]
# [('s', 'http://www.wikidata.org/entity/Q8197013'), ('sName', 'Amancio Muñoz de Zafra'), ('p', 'http://www.wikidata.org/prop/direct/P1038'), ('pName', 'relative'), ('o', 'http://www.wikidata.org/entity/Q105753880'), ('oName', 'Mateo Egea')]
# [('s', 'http://www.wikidata.org/entity/Q8199438'), ('sName', 'Andrés de Sola'), ('p', 'http://www.wikidata.org/prop/direct/P1066'), ('pName', 'student of'), ('o', 'http://www.wikidata.org/entity/Q11686949'), ('oName', 'José Ximénez')]
# [('s', 'http://www.wikidata.org/entity/Q8200247'), ('sName', 'Annette Aiello'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('pName', 'occupation'), ('o', 'http://www.wikidata.org/entity/Q12368980'), ('oName', 'nature photographer')]
# [('s', 'http://www.wikidata.org/entity/Q8200247'), ('sName', 'Annette Aiello'), ('p', 'http://www.wikidata.org/prop/direct/P108'), ('pName', 'employer'), ('o', 'http://www.wikidata.org/entity/Q1673980'), ('oName', 'Smithsonian Tropical Research Institute')]
# [('s', 'http://www.wikidata.org/entity/Q8200777'), ('sName', 'Anthony Walker'), ('p', 'http://www.wikidata.org/prop/direct/P1343'), ('pName', 'described by source'), ('o', 'http://www.wikidata.org/entity/Q17037575'), ('oName', 'Oxford Biography Index')]
# [('s', 'http://www.wikidata.org/entity/Q8202323'), ('sName', 'Alcainça-Moinhos halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q8202353'), ('sName', 'Bicanho Halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q8213303'), ('sName', 'Bunguran Utara'), ('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q10100'), ('oName', 'Natuna')]
# [('s', 'http://www.wikidata.org/entity/Q8779275'), ('sName', 'Amieira train station'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q8841005'), ('sName', 'Malveira train station'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q95452024'), ('sName', 'Template:Vice Presidents of the Maldives'), ('p', 'http://www.wikidata.org/prop/direct/P1423'), ('pName', 'template has topic'), ('o', 'http://www.wikidata.org/entity/Q10999435'), ('oName', 'Vice President of the Maldives')]
# [('s', 'http://www.wikidata.org/entity/Q81904264'), ('sName', 'Kim Ji-min'), ('p', 'http://www.wikidata.org/prop/direct/P1344'), ('pName', 'participant in'), ('o', 'http://www.wikidata.org/entity/Q1053559'), ('oName', '2020 Winter Youth Olympics')]
# [('s', 'http://www.wikidata.org/entity/Q17211428'), ('sName', 'Shigahondōri, Nagoya'), ('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q1207964'), ('oName', 'Kita-ku')]
# [('s', 'http://www.wikidata.org/entity/Q17218089'), ('sName', 'Shimmei-chō, Nagoya'), ('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q1207964'), ('oName', 'Kita-ku')]
# [('s', 'http://www.wikidata.org/entity/Q17222169'), ('sName', 'Yanagihara, Nagoya'), ('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q1207964'), ('oName', 'Kita-ku')]
# [('s', 'http://www.wikidata.org/entity/Q17228019'), ('sName', 'Onari-tōri, Nagoya'), ('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q1207964'), ('oName', 'Kita-ku')]
# [('s', 'http://www.wikidata.org/entity/Q17482735'), ('sName', 'Turó de Montcortal'), ('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q13010'), ('oName', 'Arbúcies')]
# [('s', 'http://www.wikidata.org/entity/Q17482780'), ('sName', 'Turó de Montsoriu'), ('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q13010'), ('oName', 'Arbúcies')]
# [('s', 'http://www.wikidata.org/entity/Q17588022'), ('sName', 'Bassa de la Farga'), ('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q13010'), ('oName', 'Arbúcies')]
# [('s', 'http://www.wikidata.org/entity/Q17614805'), ('sName', 'muntanya de Can Fonoll'), ('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q13010'), ('oName', 'Arbúcies')]
# [('s', 'http://www.wikidata.org/entity/Q5289551'), ('sName', 'Dolores Piperno'), ('p', 'http://www.wikidata.org/prop/direct/P108'), ('pName', 'employer'), ('o', 'http://www.wikidata.org/entity/Q1673980'), ('oName', 'Smithsonian Tropical Research Institute')]
# [('s', 'http://www.wikidata.org/entity/Q91336419'), ('sName', 'Tommy Merlyn'), ('p', 'http://www.wikidata.org/prop/direct/P119'), ('pName', 'place of burial'), ('o', 'http://www.wikidata.org/entity/Q1419655'), ('oName', 'Star City')]
# [('s', 'http://www.wikidata.org/entity/Q91376977'), ('sName', 'Monica Munoz-Torres'), ('p', 'http://www.wikidata.org/prop/direct/P108'), ('pName', 'employer'), ('o', 'http://www.wikidata.org/entity/Q1673980'), ('oName', 'Smithsonian Tropical Research Institute')]
# [('s', 'http://www.wikidata.org/entity/Q30902089'), ('sName', 'Luis Manuel Fernández'), ('p', 'http://www.wikidata.org/prop/direct/P108'), ('pName', 'employer'), ('o', 'http://www.wikidata.org/entity/Q1475831'), ('oName', 'Venezolana de Televisión')]
# [('s', 'http://www.wikidata.org/entity/Q60684635'), ('sName', 'S. Joseph Wright'), ('p', 'http://www.wikidata.org/prop/direct/P108'), ('pName', 'employer'), ('o', 'http://www.wikidata.org/entity/Q1673980'), ('oName', 'Smithsonian Tropical Research Institute')]
# [('s', 'http://www.wikidata.org/entity/Q38780585'), ('sName', 'First Minister of British Honduras'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q1643555'), ('oName', 'British Honduras')]
# [('s', 'http://www.wikidata.org/entity/Q11325962'), ('sName', 'Hyatt Regency Kyoto'), ('p', 'http://www.wikidata.org/prop/direct/P127'), ('pName', 'owned by'), ('o', 'http://www.wikidata.org/entity/Q11292651'), ('oName', 'Orix Real Estate')]
# [('s', 'http://www.wikidata.org/entity/Q18527476'), ('sName', 'David Brown'), ('p', 'http://www.wikidata.org/prop/direct/P1343'), ('pName', 'described by source'), ('o', 'http://www.wikidata.org/entity/Q17037575'), ('oName', 'Oxford Biography Index')]
# [('s', 'http://www.wikidata.org/entity/Q10863554'), ('sName', 'Ryūgasaki Domain'), ('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q1055353'), ('oName', 'Hitachi Province')]
# [('s', 'http://www.wikidata.org/entity/Q18005572'), ('sName', "Serra d'en Pere Bord"), ('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q13010'), ('oName', 'Arbúcies')]
# [('s', 'http://www.wikidata.org/entity/Q18529777'), ('sName', 'James Brown'), ('p', 'http://www.wikidata.org/prop/direct/P1343'), ('pName', 'described by source'), ('o', 'http://www.wikidata.org/entity/Q17037575'), ('oName', 'Oxford Biography Index')]
# [('s', 'http://www.wikidata.org/entity/Q18530178'), ('sName', 'John Brown'), ('p', 'http://www.wikidata.org/prop/direct/P1343'), ('pName', 'described by source'), ('o', 'http://www.wikidata.org/entity/Q17037575'), ('oName', 'Oxford Biography Index')]
# [('s', 'http://www.wikidata.org/entity/Q18810862'), ('sName', 'John Robinson'), ('p', 'http://www.wikidata.org/prop/direct/P1343'), ('pName', 'described by source'), ('o', 'http://www.wikidata.org/entity/Q17037575'), ('oName', 'Oxford Biography Index')]
# [('s', 'http://www.wikidata.org/entity/Q18810881'), ('sName', 'John Merry Ross'), ('p', 'http://www.wikidata.org/prop/direct/P1343'), ('pName', 'described by source'), ('o', 'http://www.wikidata.org/entity/Q17037575'), ('oName', 'Oxford Biography Index')]
# [('s', 'http://www.wikidata.org/entity/Q21338376'), ('sName', 'George R. Angehr'), ('p', 'http://www.wikidata.org/prop/direct/P108'), ('pName', 'employer'), ('o', 'http://www.wikidata.org/entity/Q1673980'), ('oName', 'Smithsonian Tropical Research Institute')]
# [('s', 'http://www.wikidata.org/entity/Q108386354'), ('sName', 'William P. Leonard'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('pName', 'occupation'), ('o', 'http://www.wikidata.org/entity/Q12368980'), ('oName', 'nature photographer')]
# [('s', 'http://www.wikidata.org/entity/Q64910919'), ('sName', 'Subish Palaian'), ('p', 'http://www.wikidata.org/prop/direct/P108'), ('pName', 'employer'), ('o', 'http://www.wikidata.org/entity/Q12204508'), ('oName', 'Ajman University')]
# [('s', 'http://www.wikidata.org/entity/Q57161562'), ('sName', 'Michiel van Breugel'), ('p', 'http://www.wikidata.org/prop/direct/P108'), ('pName', 'employer'), ('o', 'http://www.wikidata.org/entity/Q1673980'), ('oName', 'Smithsonian Tropical Research Institute')]
# [('s', 'http://www.wikidata.org/entity/Q76449094'), ('sName', 'Victoria Stirnemann'), ('p', 'http://www.wikidata.org/prop/direct/P1344'), ('pName', 'participant in'), ('o', 'http://www.wikidata.org/entity/Q1053559'), ('oName', '2020 Winter Youth Olympics')]
# [('s', 'http://www.wikidata.org/entity/Q81904099'), ('sName', 'Benjamin Kapp'), ('p', 'http://www.wikidata.org/prop/direct/P1344'), ('pName', 'participant in'), ('o', 'http://www.wikidata.org/entity/Q1053559'), ('oName', '2020 Winter Youth Olympics')]
# [('s', 'http://www.wikidata.org/entity/Q1749545'), ('sName', 'Nova Zagora Municipality'), ('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q113120'), ('oName', 'Sliven Province')]
# [('s', 'http://www.wikidata.org/entity/Q3031457'), ('sName', 'Mananjary'), ('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q1462671'), ('oName', 'Vatovavy-Fitovinany')]
# [('s', 'http://www.wikidata.org/entity/Q7850092'), ('sName', 'Tsukuba district'), ('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q1055353'), ('oName', 'Hitachi Province')]
# [('s', 'http://www.wikidata.org/entity/Q24232048'), ('sName', 'Pulau Tiga Barat'), ('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q10100'), ('oName', 'Natuna')]
# [('s', 'http://www.wikidata.org/entity/Q8213242'), ('sName', 'Pulau Tiga'), ('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q10100'), ('oName', 'Natuna')]
# [('s', 'http://www.wikidata.org/entity/Q18526878'), ('sName', 'John Evans'), ('p', 'http://www.wikidata.org/prop/direct/P1343'), ('pName', 'described by source'), ('o', 'http://www.wikidata.org/entity/Q17037575'), ('oName', 'Oxford Biography Index')]
# [('s', 'http://www.wikidata.org/entity/Q18527381'), ('sName', 'John Murray'), ('p', 'http://www.wikidata.org/prop/direct/P1343'), ('pName', 'described by source'), ('o', 'http://www.wikidata.org/entity/Q17037575'), ('oName', 'Oxford Biography Index')]
# [('s', 'http://www.wikidata.org/entity/Q18527772'), ('sName', 'John Walker'), ('p', 'http://www.wikidata.org/prop/direct/P1343'), ('pName', 'described by source'), ('o', 'http://www.wikidata.org/entity/Q17037575'), ('oName', 'Oxford Biography Index')]
# [('s', 'http://www.wikidata.org/entity/Q18529684'), ('sName', 'David Davies'), ('p', 'http://www.wikidata.org/prop/direct/P1343'), ('pName', 'described by source'), ('o', 'http://www.wikidata.org/entity/Q17037575'), ('oName', 'Oxford Biography Index')]
# [('s', 'http://www.wikidata.org/entity/Q18530173'), ('sName', 'John Brown'), ('p', 'http://www.wikidata.org/prop/direct/P1343'), ('pName', 'described by source'), ('o', 'http://www.wikidata.org/entity/Q17037575'), ('oName', 'Oxford Biography Index')]
# [('s', 'http://www.wikidata.org/entity/Q18530181'), ('sName', 'John Wright Brown'), ('p', 'http://www.wikidata.org/prop/direct/P1343'), ('pName', 'described by source'), ('o', 'http://www.wikidata.org/entity/Q17037575'), ('oName', 'Oxford Biography Index')]
# [('s', 'http://www.wikidata.org/entity/Q18534214'), ('sName', 'John Taylor'), ('p', 'http://www.wikidata.org/prop/direct/P1343'), ('pName', 'described by source'), ('o', 'http://www.wikidata.org/entity/Q17037575'), ('oName', 'Oxford Biography Index')]
# [('s', 'http://www.wikidata.org/entity/Q18546621'), ('sName', 'John Roland Phillips'), ('p', 'http://www.wikidata.org/prop/direct/P1343'), ('pName', 'described by source'), ('o', 'http://www.wikidata.org/entity/Q17037575'), ('oName', 'Oxford Biography Index')]
# [('s', 'http://www.wikidata.org/entity/Q18546651'), ('sName', 'John Williams'), ('p', 'http://www.wikidata.org/prop/direct/P1343'), ('pName', 'described by source'), ('o', 'http://www.wikidata.org/entity/Q17037575'), ('oName', 'Oxford Biography Index')]
# [('s', 'http://www.wikidata.org/entity/Q18546656'), ('sName', 'John Bickerton Williams'), ('p', 'http://www.wikidata.org/prop/direct/P1343'), ('pName', 'described by source'), ('o', 'http://www.wikidata.org/entity/Q17037575'), ('oName', 'Oxford Biography Index')]
# [('s', 'http://www.wikidata.org/entity/Q7528143'), ('sName', 'Sir John Williams, 1st Baronet, of the City of London'), ('p', 'http://www.wikidata.org/prop/direct/P1343'), ('pName', 'described by source'), ('o', 'http://www.wikidata.org/entity/Q17037575'), ('oName', 'Oxford Biography Index')]
# [('s', 'http://www.wikidata.org/entity/Q18593621'), ('sName', 'William Moore'), ('p', 'http://www.wikidata.org/prop/direct/P1343'), ('pName', 'described by source'), ('o', 'http://www.wikidata.org/entity/Q17037575'), ('oName', 'Oxford Biography Index')]
# [('s', 'http://www.wikidata.org/entity/Q18729868'), ('sName', 'Entesa per Arbúcies'), ('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q13010'), ('oName', 'Arbúcies')]
# [('s', 'http://www.wikidata.org/entity/Q12475627'), ('sName', 'Belimbing, Melawi'), ('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q14162'), ('oName', 'Melawi')]
# [('s', 'http://www.wikidata.org/entity/Q8213273'), ('sName', 'Serasan'), ('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q10100'), ('oName', 'Natuna')]
# [('s', 'http://www.wikidata.org/entity/Q1905256'), ('sName', 'Martin Wikelski'), ('p', 'http://www.wikidata.org/prop/direct/P108'), ('pName', 'employer'), ('o', 'http://www.wikidata.org/entity/Q1673980'), ('oName', 'Smithsonian Tropical Research Institute')]
# [('s', 'http://www.wikidata.org/entity/Q21611757'), ('sName', 'Juan Carlos Villarreal Aguilar'), ('p', 'http://www.wikidata.org/prop/direct/P108'), ('pName', 'employer'), ('o', 'http://www.wikidata.org/entity/Q1673980'), ('oName', 'Smithsonian Tropical Research Institute')]
# [('s', 'http://www.wikidata.org/entity/Q24035454'), ('sName', 'el Vidal'), ('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q13010'), ('oName', 'Arbúcies')]
# [('s', 'http://www.wikidata.org/entity/Q57080337'), ('sName', 'David I Kline'), ('p', 'http://www.wikidata.org/prop/direct/P108'), ('pName', 'employer'), ('o', 'http://www.wikidata.org/entity/Q1673980'), ('oName', 'Smithsonian Tropical Research Institute')]
# [('s', 'http://www.wikidata.org/entity/Q44790072'), ('sName', 'Sean R. Connolly'), ('p', 'http://www.wikidata.org/prop/direct/P108'), ('pName', 'employer'), ('o', 'http://www.wikidata.org/entity/Q1673980'), ('oName', 'Smithsonian Tropical Research Institute')]
# [('s', 'http://www.wikidata.org/entity/Q60297756'), ('sName', 'Orpheus M Butler'), ('p', 'http://www.wikidata.org/prop/direct/P108'), ('pName', 'employer'), ('o', 'http://www.wikidata.org/entity/Q1673980'), ('oName', 'Smithsonian Tropical Research Institute')]
# [('s', 'http://www.wikidata.org/entity/Q19294986'), ('sName', 'Louis Berlioz'), ('p', 'http://www.wikidata.org/prop/direct/P101'), ('pName', 'field of work'), ('o', 'http://www.wikidata.org/entity/Q121713'), ('oName', 'acupuncture')]
# [('s', 'http://www.wikidata.org/entity/Q7980959'), ('sName', 'welfare fraud'), ('p', 'http://www.wikidata.org/prop/direct/P1269'), ('pName', 'facet of'), ('o', 'http://www.wikidata.org/entity/Q11497309'), ('oName', 'economic support')]
# [('s', 'http://www.wikidata.org/entity/Q7371387'), ('sName', 'Nagoya Expressway 16'), ('p', 'http://www.wikidata.org/prop/direct/P126'), ('pName', 'maintained by'), ('o', 'http://www.wikidata.org/entity/Q11415304'), ('oName', 'Nagoya Expressway Public Corporation')]
# [('s', 'http://www.wikidata.org/entity/Q80545'), ('sName', 'Oshiage Station'), ('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q11497641'), ('oName', 'Oshiage')]
# [('s', 'http://www.wikidata.org/entity/Q8191440'), ('sName', 'Nagoya Highway 11'), ('p', 'http://www.wikidata.org/prop/direct/P126'), ('pName', 'maintained by'), ('o', 'http://www.wikidata.org/entity/Q11415304'), ('oName', 'Nagoya Expressway Public Corporation')]
# [('s', 'http://www.wikidata.org/entity/Q8191440'), ('sName', 'Nagoya Highway 11'), ('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q1207964'), ('oName', 'Kita-ku')]
# [('s', 'http://www.wikidata.org/entity/Q8191440'), ('sName', 'Nagoya Highway 11'), ('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q1345562'), ('oName', 'Toyoyama')]
# [('s', 'http://www.wikidata.org/entity/Q4423406'), ('sName', 'Sliven Municipality'), ('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q113120'), ('oName', 'Sliven Province')]
# [('s', 'http://www.wikidata.org/entity/Q25563103'), ('sName', 'Warangal'), ('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q15399'), ('oName', 'Warangal District')]
# [('s', 'http://www.wikidata.org/entity/Q12383937'), ('sName', 'Augas Santas, Allariz'), ('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q1438879'), ('oName', 'Allariz')]
# [('s', 'http://www.wikidata.org/entity/Q2609479'), ('sName', 'Kotel Municipality'), ('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q113120'), ('oName', 'Sliven Province')]
# [('s', 'http://www.wikidata.org/entity/Q11494799'), ('sName', 'Aichi Prefectural Road Route 62'), ('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q1345562'), ('oName', 'Toyoyama')]
# [('s', 'http://www.wikidata.org/entity/Q12358779'), ('sName', 'Aleksandr Podkopajev'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('pName', 'occupation'), ('o', 'http://www.wikidata.org/entity/Q106823762'), ('oName', 'veterinary scientist')]
# [('s', 'http://www.wikidata.org/entity/Q12371070'), ('sName', 'Nikolai Prozorov'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('pName', 'occupation'), ('o', 'http://www.wikidata.org/entity/Q106823762'), ('oName', 'veterinary scientist')]
# [('s', 'http://www.wikidata.org/entity/Q12482400'), ('sName', 'Ella Hilir'), ('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q14162'), ('oName', 'Melawi')]
# [('s', 'http://www.wikidata.org/entity/Q8213279'), ('sName', 'Midai'), ('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q10100'), ('oName', 'Natuna')]
# 100

# %%
# Consider the tennis players born after 1975, return who won more Grand Slams and cut the result to the top-10 (the result set must be a list of triples player IRI, label and #victories).
# Q1426 = Roger Federer
# wdt:P1344 (participant in)
# wdt:P2522 (victory)
#[('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('o', 'http://www.wikidata.org/entity/P569'), ('oName', 'date of birth')]
# 1) getting winners dob 

queryString = """

SELECT DISTINCT ?s ?sName ?p ?pName ?o ?oName
WHERE {
   # ?s ?p ?o.
   # ?s sc:name ?sName.
   # ?p sc:name ?pName.
   # ?o sc:name ?oName.
   
   #it never returns the result if un-comment the filter
   FILTER (REGEX(?pName,"[D|d][O|o][B|b]"))
}
LIMIT 10
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('s', 'http://www.wikidata.org/entity/Q95452024'), ('sName', 'Template:Vice Presidents of the Maldives'), ('p', 'http://www.wikidata.org/prop/direct/P1423'), ('pName', 'template has topic'), ('o', 'http://www.wikidata.org/entity/Q10999435'), ('oName', 'Vice President of the Maldives')]
# [('s', 'http://www.wikidata.org/entity/Q25752552'), ('sName', 'Template:2001 in Europe'), ('p', 'http://www.wikidata.org/prop/direct/P1423'), ('pName', 'template has topic'), ('o', 'http://www.wikidata.org/entity/Q17111750'), ('oName', '2001 in Europe')]
# [('s', 'http://www.wikidata.org/entity/Q6675314'), ('sName', 'Template:Alcest'), ('p', 'http://www.wikidata.org/prop/direct/P1423'), ('pName', 'template has topic'), ('o', 'http://www.wikidata.org/entity/Q1517060'), ('oName', 'Alcest')]
# [('s', 'http://www.wikidata.org/entity/Q22785857'), ('sName', 'Template:2006 in Europe'), ('p', 'http://www.wikidata.org/prop/direct/P1423'), ('pName', 'template has topic'), ('o', 'http://www.wikidata.org/entity/Q17111782'), ('oName', '2006 in Europe')]
# [('s', 'http://www.wikidata.org/entity/Q85816744'), ('sName', 'Yodli'), ('p', 'http://www.wikidata.org/prop/direct/P1268'), ('pName', 'represents'), ('o', 'http://www.wikidata.org/entity/Q1053559'), ('oName', '2020 Winter Youth Olympics')]
# [('s', 'http://www.wikidata.org/entity/Q1064606'), ('sName', 'President of the Maldives'), ('p', 'http://www.wikidata.org/prop/direct/P2098'), ('pName', 'substitute/deputy/replacement of office/officeholder'), ('o', 'http://www.wikidata.org/entity/Q10999435'), ('oName', 'Vice President of the Maldives')]
# [('s', 'http://www.wikidata.org/entity/Q10275776'), ('sName', 'Estação Ferroviária de Mafra'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q18483474'), ('sName', 'Telhada halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q8202323'), ('sName', 'Alcainça-Moinhos halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q8202353'), ('sName', 'Bicanho Halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# 10

# %%
# Consider the tennis players born after 1975, return who won more Grand Slams and cut the result to the top-10 (the result set must be a list of triples player IRI, label and #victories).
# Q1426 = Roger Federer
# wdt:P1344 (participant in)
# wdt:P2522 (victory)
#[('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('o', 'http://www.wikidata.org/entity/P569'), ('oName', 'date of birth')]
# 1) getting winners dob 

queryString = """

SELECT DISTINCT ?s ?sName ?p ?pName ?o ?oName
WHERE {
   # ?s ?p ?o.
   # ?s sc:name ?sName.
   # ?p sc:name ?pName.
   # ?o sc:name ?oName.
   
   # Sometime it returns the result and other it doesn't #comment the filter
   FILTER (REGEX(?pName,"date.*"))
}
LIMIT 10
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('s', 'http://www.wikidata.org/entity/Q95452024'), ('sName', 'Template:Vice Presidents of the Maldives'), ('p', 'http://www.wikidata.org/prop/direct/P1423'), ('pName', 'template has topic'), ('o', 'http://www.wikidata.org/entity/Q10999435'), ('oName', 'Vice President of the Maldives')]
# [('s', 'http://www.wikidata.org/entity/Q25752552'), ('sName', 'Template:2001 in Europe'), ('p', 'http://www.wikidata.org/prop/direct/P1423'), ('pName', 'template has topic'), ('o', 'http://www.wikidata.org/entity/Q17111750'), ('oName', '2001 in Europe')]
# [('s', 'http://www.wikidata.org/entity/Q6675314'), ('sName', 'Template:Alcest'), ('p', 'http://www.wikidata.org/prop/direct/P1423'), ('pName', 'template has topic'), ('o', 'http://www.wikidata.org/entity/Q1517060'), ('oName', 'Alcest')]
# [('s', 'http://www.wikidata.org/entity/Q22785857'), ('sName', 'Template:2006 in Europe'), ('p', 'http://www.wikidata.org/prop/direct/P1423'), ('pName', 'template has topic'), ('o', 'http://www.wikidata.org/entity/Q17111782'), ('oName', '2006 in Europe')]
# [('s', 'http://www.wikidata.org/entity/Q85816744'), ('sName', 'Yodli'), ('p', 'http://www.wikidata.org/prop/direct/P1268'), ('pName', 'represents'), ('o', 'http://www.wikidata.org/entity/Q1053559'), ('oName', '2020 Winter Youth Olympics')]
# [('s', 'http://www.wikidata.org/entity/Q1064606'), ('sName', 'President of the Maldives'), ('p', 'http://www.wikidata.org/prop/direct/P2098'), ('pName', 'substitute/deputy/replacement of office/officeholder'), ('o', 'http://www.wikidata.org/entity/Q10999435'), ('oName', 'Vice President of the Maldives')]
# [('s', 'http://www.wikidata.org/entity/Q10275776'), ('sName', 'Estação Ferroviária de Mafra'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q18483474'), ('sName', 'Telhada halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q8202323'), ('sName', 'Alcainça-Moinhos halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q8202353'), ('sName', 'Bicanho Halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# 10

# %%
# Consider the tennis players born after 1975, return who won more Grand Slams and cut the result to the top-10 (the result set must be a list of triples player IRI, label and #victories).
# Q1426 = Roger Federer
# wdt:P1344 (participant in)
# wdt:P2522 (victory)
#[('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('o', 'http://www.wikidata.org/entity/P569'), ('oName', 'date of birth')]
# 1) getting winners dob 

queryString = """

SELECT DISTINCT ?s ?sName ?p ?pName ?o ?oName
WHERE {
   # ?s ?p ?o.
   # ?s sc:name ?sName.
   # ?p sc:name ?pName.
   # ?o sc:name ?oName.
   
   # sometimes filter with regex don't work
   FILTER (REGEX(?pName,"date","i"))
   #FILTER (?p not in (wdt:P726, wdt:P991))
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('s', 'http://www.wikidata.org/entity/Q95452024'), ('sName', 'Template:Vice Presidents of the Maldives'), ('p', 'http://www.wikidata.org/prop/direct/P1423'), ('pName', 'template has topic'), ('o', 'http://www.wikidata.org/entity/Q10999435'), ('oName', 'Vice President of the Maldives')]
# [('s', 'http://www.wikidata.org/entity/Q25752552'), ('sName', 'Template:2001 in Europe'), ('p', 'http://www.wikidata.org/prop/direct/P1423'), ('pName', 'template has topic'), ('o', 'http://www.wikidata.org/entity/Q17111750'), ('oName', '2001 in Europe')]
# [('s', 'http://www.wikidata.org/entity/Q6675314'), ('sName', 'Template:Alcest'), ('p', 'http://www.wikidata.org/prop/direct/P1423'), ('pName', 'template has topic'), ('o', 'http://www.wikidata.org/entity/Q1517060'), ('oName', 'Alcest')]
# [('s', 'http://www.wikidata.org/entity/Q22785857'), ('sName', 'Template:2006 in Europe'), ('p', 'http://www.wikidata.org/prop/direct/P1423'), ('pName', 'template has topic'), ('o', 'http://www.wikidata.org/entity/Q17111782'), ('oName', '2006 in Europe')]
# [('s', 'http://www.wikidata.org/entity/Q85816744'), ('sName', 'Yodli'), ('p', 'http://www.wikidata.org/prop/direct/P1268'), ('pName', 'represents'), ('o', 'http://www.wikidata.org/entity/Q1053559'), ('oName', '2020 Winter Youth Olympics')]
# [('s', 'http://www.wikidata.org/entity/Q1064606'), ('sName', 'President of the Maldives'), ('p', 'http://www.wikidata.org/prop/direct/P2098'), ('pName', 'substitute/deputy/replacement of office/officeholder'), ('o', 'http://www.wikidata.org/entity/Q10999435'), ('oName', 'Vice President of the Maldives')]
# [('s', 'http://www.wikidata.org/entity/Q10275776'), ('sName', 'Estação Ferroviária de Mafra'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q18483474'), ('sName', 'Telhada halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q8202323'), ('sName', 'Alcainça-Moinhos halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q8202353'), ('sName', 'Bicanho Halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q8779275'), ('sName', 'Amieira train station'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q8841005'), ('sName', 'Malveira train station'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q17267254'), ('sName', 'Fanhais halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q17267315'), ('sName', 'Cela halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q8779401'), ('sName', 'Bombarral train station'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q8840924'), ('sName', 'Leiria train station'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q8841025'), ('sName', 'Marinha Grande station'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q8841035'), ('sName', 'Martingança train station'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q8841427'), ('sName', 'Pataias train station'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q8842140'), ('sName', 'Valado train station'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q248226'), ('sName', 'Agualva-Cacém railway station'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q18482873'), ('sName', 'Fontela halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q18482882'), ('sName', 'Fontela-A halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q18482941'), ('sName', 'Jerumelo halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q18483298'), ('sName', 'Salir do Porto halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q18483365'), ('sName', 'Sapataria Halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q800752'), ('sName', 'Figueira da Foz train station'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q8841452'), ('sName', 'Pero Negro train station'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q8841387'), ('sName', 'Outeiro train station'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q10275790'), ('sName', 'Sabugo train station'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q16781965'), ('sName', 'Pedra Furada halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q16781966'), ('sName', 'Telhal halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q17000336'), ('sName', 'Óbidos halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q587866'), ('sName', 'Estação Ferroviária de Caldas da Rainha'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q18482975'), ('sName', 'Lares halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q557982'), ('sName', 'Bifurcação de Lares train station'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q10275797'), ('sName', 'São Martinho do Porto train station'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q18482831'), ('sName', 'Famalicão da Nazaré halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q8841053'), ('sName', 'Mira Sintra-Meleças train station'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q10275778'), ('sName', 'Monte Real train station'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q18482642'), ('sName', 'Carriço halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q18482848'), ('sName', 'Feliteira halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q18482932'), ('sName', 'Guia halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q19702819'), ('sName', 'Monte Redondo halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q19702893'), ('sName', 'Zibreira halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q5552454'), ('sName', 'Dois Porto train station'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q8840980'), ('sName', 'Louriçal train station'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q18483271'), ('sName', 'Regueira de Pontes halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q8841573'), ('sName', 'Ramalhal train station'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q8842080'), ('sName', 'Torres Vedras train station'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q18483280'), ('sName', 'Ribeira de Seiça halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q19702853'), ('sName', 'Runa halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q18483456'), ('sName', 'São Mamede halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q38780585'), ('sName', 'First Minister of British Honduras'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q1643555'), ('oName', 'British Honduras')]
# [('s', 'http://www.wikidata.org/entity/Q26691790'), ('sName', 'mayor of Sant Pere Sallavinera'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q15967'), ('oName', 'Sant Pere Sallavinera')]
# [('s', 'http://www.wikidata.org/entity/Q105998262'), ('sName', 'Mayor of Star City'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q1419655'), ('oName', 'Star City')]
# [('s', 'http://www.wikidata.org/entity/Q108080825'), ('sName', 'Attorney-General of British Honduras'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q1643555'), ('oName', 'British Honduras')]
# [('s', 'http://www.wikidata.org/entity/Q26691184'), ('sName', 'mayor of Ripollet'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q13933'), ('oName', 'Ripollet')]
# [('s', 'http://www.wikidata.org/entity/Q56438477'), ('sName', 'mayor of Itano'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q1350904'), ('oName', 'Itano')]
# [('s', 'http://www.wikidata.org/entity/Q59773367'), ('sName', 'Arbúcies city councillor'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q13010'), ('oName', 'Arbúcies')]
# [('s', 'http://www.wikidata.org/entity/Q11907924'), ('sName', 'Flag of Ripollet'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q13933'), ('oName', 'Ripollet')]
# [('s', 'http://www.wikidata.org/entity/Q105514924'), ('sName', 'Ripollet results in 2021 Catalan parliamentary election'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q13933'), ('oName', 'Ripollet')]
# [('s', 'http://www.wikidata.org/entity/Q26695213'), ('sName', 'mayor of Pedreguer'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q1750923'), ('oName', 'Pedreguer')]
# [('s', 'http://www.wikidata.org/entity/Q44952776'), ('sName', 'Catalan regional election 2015 in Sant Pere Sallavinera'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q15967'), ('oName', 'Sant Pere Sallavinera')]
# [('s', 'http://www.wikidata.org/entity/Q101978391'), ('sName', 'Regional Regulation of Melawi Regency Number 04 Year 2018'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q14162'), ('oName', 'Melawi')]
# [('s', 'http://www.wikidata.org/entity/Q11481685'), ('sName', 'Hitachi Kokubunji'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q1055353'), ('oName', 'Hitachi Province')]
# [('s', 'http://www.wikidata.org/entity/Q26691392'), ('sName', 'mayor of Zalduendo de Álava'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q1443609'), ('oName', 'Zalduondo')]
# [('s', 'http://www.wikidata.org/entity/Q26695389'), ('sName', 'mayor of Cehegín'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q1757489'), ('oName', 'Cehegín')]
# [('s', 'http://www.wikidata.org/entity/Q62051046'), ('sName', 'Legislative Assembly of British Honduras'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q1643555'), ('oName', 'British Honduras')]
# [('s', 'http://www.wikidata.org/entity/Q26690765'), ('sName', 'mayor of Arbúcies'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q13010'), ('oName', 'Arbúcies')]
# [('s', 'http://www.wikidata.org/entity/Q105515175'), ('sName', 'Arbúcies results in 2021 Catalan parliamentary election'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q13010'), ('oName', 'Arbúcies')]
# [('s', 'http://www.wikidata.org/entity/Q44914898'), ('sName', 'Catalan regional election 2015 in Ripollet'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q13933'), ('oName', 'Ripollet')]
# [('s', 'http://www.wikidata.org/entity/Q45023173'), ('sName', 'Catalan regional election 2015 in Arbúcies'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q13010'), ('oName', 'Arbúcies')]
# [('s', 'http://www.wikidata.org/entity/Q56402053'), ('sName', 'Flag of Sant Pere Sallavinera'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q15967'), ('oName', 'Sant Pere Sallavinera')]
# [('s', 'http://www.wikidata.org/entity/Q56437866'), ('sName', 'mayor of Toyoyama'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q1345562'), ('oName', 'Toyoyama')]
# [('s', 'http://www.wikidata.org/entity/Q105514933'), ('sName', 'Sant Pere Sallavinera results in 2021 Catalan parliamentary election'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q15967'), ('oName', 'Sant Pere Sallavinera')]
# [('s', 'http://www.wikidata.org/entity/Q105482504'), ('sName', 'Arbúcies results in 2017 Catalan parliamentary election'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q13010'), ('oName', 'Arbúcies')]
# [('s', 'http://www.wikidata.org/entity/Q105482709'), ('sName', 'Ripollet results in 2017 Catalan parliamentary election'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q13933'), ('oName', 'Ripollet')]
# [('s', 'http://www.wikidata.org/entity/Q11481689'), ('sName', 'Hitachinokuni Sōshagū'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q1055353'), ('oName', 'Hitachi Province')]
# [('s', 'http://www.wikidata.org/entity/Q105481195'), ('sName', 'Sant Pere Sallavinera results in 2017 Catalan parliamentary election'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q15967'), ('oName', 'Sant Pere Sallavinera')]
# [('s', 'http://www.wikidata.org/entity/Q19294986'), ('sName', 'Louis Berlioz'), ('p', 'http://www.wikidata.org/prop/direct/P101'), ('pName', 'field of work'), ('o', 'http://www.wikidata.org/entity/Q121713'), ('oName', 'acupuncture')]
# [('s', 'http://www.wikidata.org/entity/Q64392269'), ('sName', 'Ian Gough'), ('p', 'http://www.wikidata.org/prop/direct/P101'), ('pName', 'field of work'), ('o', 'http://www.wikidata.org/entity/Q11497309'), ('oName', 'economic support')]
# [('s', 'http://www.wikidata.org/entity/Q19957642'), ('sName', 'Ruby Duncan'), ('p', 'http://www.wikidata.org/prop/direct/P101'), ('pName', 'field of work'), ('o', 'http://www.wikidata.org/entity/Q11497309'), ('oName', 'economic support')]
# [('s', 'http://www.wikidata.org/entity/Q81425306'), ('sName', 'Physiotherapy Douma'), ('p', 'http://www.wikidata.org/prop/direct/P101'), ('pName', 'field of work'), ('o', 'http://www.wikidata.org/entity/Q121713'), ('oName', 'acupuncture')]
# [('s', 'http://www.wikidata.org/entity/Q15809258'), ('sName', 'Healer of Berne'), ('p', 'http://www.wikidata.org/prop/direct/P101'), ('pName', 'field of work'), ('o', 'http://www.wikidata.org/entity/Q121713'), ('oName', 'acupuncture')]
# [('s', 'http://www.wikidata.org/entity/Q66535461'), ('sName', 'Emmanuel Kreike'), ('p', 'http://www.wikidata.org/prop/direct/P101'), ('pName', 'field of work'), ('o', 'http://www.wikidata.org/entity/Q11497309'), ('oName', 'economic support')]
# [('s', 'http://www.wikidata.org/entity/Q6066216'), ('sName', 'Ira Rubinoff'), ('p', 'http://www.wikidata.org/prop/direct/P101'), ('pName', 'field of work'), ('o', 'http://www.wikidata.org/entity/Q1673980'), ('oName', 'Smithsonian Tropical Research Institute')]
# [('s', 'http://www.wikidata.org/entity/Q55600270'), ('sName', 'Élise Boghossian'), ('p', 'http://www.wikidata.org/prop/direct/P101'), ('pName', 'field of work'), ('o', 'http://www.wikidata.org/entity/Q121713'), ('oName', 'acupuncture')]
# [('s', 'http://www.wikidata.org/entity/Q9044036'), ('sName', 'Su Yu-chang'), ('p', 'http://www.wikidata.org/prop/direct/P101'), ('pName', 'field of work'), ('o', 'http://www.wikidata.org/entity/Q121713'), ('oName', 'acupuncture')]
# [('s', 'http://www.wikidata.org/entity/Q17107163'), ('sName', 'Vilhelm Schjelderup'), ('p', 'http://www.wikidata.org/prop/direct/P101'), ('pName', 'field of work'), ('o', 'http://www.wikidata.org/entity/Q121713'), ('oName', 'acupuncture')]
# [('s', 'http://www.wikidata.org/entity/Q97147261'), ('sName', 'Clinics Dr. Erler'), ('p', 'http://www.wikidata.org/prop/direct/P101'), ('pName', 'field of work'), ('o', 'http://www.wikidata.org/entity/Q121713'), ('oName', 'acupuncture')]
# [('s', 'http://www.wikidata.org/entity/Q64175666'), ('sName', 'Jeremy Ross'), ('p', 'http://www.wikidata.org/prop/direct/P101'), ('pName', 'field of work'), ('o', 'http://www.wikidata.org/entity/Q121713'), ('oName', 'acupuncture')]
# [('s', 'http://www.wikidata.org/entity/Q96579961'), ('sName', 'Sana Clinic Nuremberg'), ('p', 'http://www.wikidata.org/prop/direct/P101'), ('pName', 'field of work'), ('o', 'http://www.wikidata.org/entity/Q121713'), ('oName', 'acupuncture')]
# [('s', 'http://www.wikidata.org/entity/Q47544113'), ('sName', 'Maesiah Thabane'), ('p', 'http://www.wikidata.org/prop/direct/P102'), ('pName', 'member of political party'), ('o', 'http://www.wikidata.org/entity/Q1346132'), ('oName', 'All Basotho Convention')]
# [('s', 'http://www.wikidata.org/entity/Q9092970'), ('sName', 'Vera Grabe'), ('p', 'http://www.wikidata.org/prop/direct/P102'), ('pName', 'member of political party'), ('o', 'http://www.wikidata.org/entity/Q1789014'), ('oName', '19th of April Movement')]
# [('s', 'http://www.wikidata.org/entity/Q5992796'), ('sName', 'Ignatius Shixwameni'), ('p', 'http://www.wikidata.org/prop/direct/P102'), ('pName', 'member of political party'), ('o', 'http://www.wikidata.org/entity/Q1129391'), ('oName', "All People's Party")]
# [('s', 'http://www.wikidata.org/entity/Q16194214'), ('sName', 'Mophato Monyake'), ('p', 'http://www.wikidata.org/prop/direct/P102'), ('pName', 'member of political party'), ('o', 'http://www.wikidata.org/entity/Q1346132'), ('oName', 'All Basotho Convention')]
# [('s', 'http://www.wikidata.org/entity/Q3660117'), ('sName', 'Carlos Pizarro Leongómez'), ('p', 'http://www.wikidata.org/prop/direct/P102'), ('pName', 'member of political party'), ('o', 'http://www.wikidata.org/entity/Q1789014'), ('oName', '19th of April Movement')]
# [('s', 'http://www.wikidata.org/entity/Q1567660'), ('sName', 'Hae Phoofolo'), ('p', 'http://www.wikidata.org/prop/direct/P102'), ('pName', 'member of political party'), ('o', 'http://www.wikidata.org/entity/Q1346132'), ('oName', 'All Basotho Convention')]
# [('s', 'http://www.wikidata.org/entity/Q4752142'), ('sName', 'Anatol Arhire'), ('p', 'http://www.wikidata.org/prop/direct/P102'), ('pName', 'member of political party'), ('o', 'http://www.wikidata.org/entity/Q1280031'), ('oName', 'Alliance for European Integration')]
# 100

# %%
# Consider the tennis players born after 1975, return who won more Grand Slams and cut the result to the top-10 (the result set must be a list of triples player IRI, label and #victories).
# Q1426 = Roger Federer
# wdt:P1344 (participant in)
# wdt:P2522 (victory)
#[('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('o', 'http://www.wikidata.org/entity/P569'), ('oName', 'date of birth')]
# 1) getting winners dob 

queryString = """

SELECT DISTINCT ?s ?sName ?p ?pName ?o ?oName
WHERE {
   # ?s ?p ?o.
   # ?s sc:name ?sName.
   # ?p sc:name ?pName.
   # ?o sc:name ?oName.
   
   #this time filter doesnt work 
   FILTER (REGEX(?pName,"year","i"))
   #FILTER (?p not in (wdt:P726, wdt:P991))
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('s', 'http://www.wikidata.org/entity/Q95452024'), ('sName', 'Template:Vice Presidents of the Maldives'), ('p', 'http://www.wikidata.org/prop/direct/P1423'), ('pName', 'template has topic'), ('o', 'http://www.wikidata.org/entity/Q10999435'), ('oName', 'Vice President of the Maldives')]
# [('s', 'http://www.wikidata.org/entity/Q25752552'), ('sName', 'Template:2001 in Europe'), ('p', 'http://www.wikidata.org/prop/direct/P1423'), ('pName', 'template has topic'), ('o', 'http://www.wikidata.org/entity/Q17111750'), ('oName', '2001 in Europe')]
# [('s', 'http://www.wikidata.org/entity/Q6675314'), ('sName', 'Template:Alcest'), ('p', 'http://www.wikidata.org/prop/direct/P1423'), ('pName', 'template has topic'), ('o', 'http://www.wikidata.org/entity/Q1517060'), ('oName', 'Alcest')]
# [('s', 'http://www.wikidata.org/entity/Q22785857'), ('sName', 'Template:2006 in Europe'), ('p', 'http://www.wikidata.org/prop/direct/P1423'), ('pName', 'template has topic'), ('o', 'http://www.wikidata.org/entity/Q17111782'), ('oName', '2006 in Europe')]
# [('s', 'http://www.wikidata.org/entity/Q85816744'), ('sName', 'Yodli'), ('p', 'http://www.wikidata.org/prop/direct/P1268'), ('pName', 'represents'), ('o', 'http://www.wikidata.org/entity/Q1053559'), ('oName', '2020 Winter Youth Olympics')]
# [('s', 'http://www.wikidata.org/entity/Q1064606'), ('sName', 'President of the Maldives'), ('p', 'http://www.wikidata.org/prop/direct/P2098'), ('pName', 'substitute/deputy/replacement of office/officeholder'), ('o', 'http://www.wikidata.org/entity/Q10999435'), ('oName', 'Vice President of the Maldives')]
# [('s', 'http://www.wikidata.org/entity/Q10275776'), ('sName', 'Estação Ferroviária de Mafra'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q18483474'), ('sName', 'Telhada halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q8202323'), ('sName', 'Alcainça-Moinhos halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q8202353'), ('sName', 'Bicanho Halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q8779275'), ('sName', 'Amieira train station'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q8841005'), ('sName', 'Malveira train station'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q17267254'), ('sName', 'Fanhais halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q17267315'), ('sName', 'Cela halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q8779401'), ('sName', 'Bombarral train station'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q8840924'), ('sName', 'Leiria train station'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q8841025'), ('sName', 'Marinha Grande station'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q8841035'), ('sName', 'Martingança train station'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q8841427'), ('sName', 'Pataias train station'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q8842140'), ('sName', 'Valado train station'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q248226'), ('sName', 'Agualva-Cacém railway station'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q18482873'), ('sName', 'Fontela halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q18482882'), ('sName', 'Fontela-A halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q18482941'), ('sName', 'Jerumelo halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q18483298'), ('sName', 'Salir do Porto halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q18483365'), ('sName', 'Sapataria Halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q800752'), ('sName', 'Figueira da Foz train station'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q8841452'), ('sName', 'Pero Negro train station'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q8841387'), ('sName', 'Outeiro train station'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q10275790'), ('sName', 'Sabugo train station'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q16781965'), ('sName', 'Pedra Furada halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q16781966'), ('sName', 'Telhal halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q17000336'), ('sName', 'Óbidos halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q587866'), ('sName', 'Estação Ferroviária de Caldas da Rainha'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q18482975'), ('sName', 'Lares halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q557982'), ('sName', 'Bifurcação de Lares train station'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q10275797'), ('sName', 'São Martinho do Porto train station'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q18482831'), ('sName', 'Famalicão da Nazaré halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q8841053'), ('sName', 'Mira Sintra-Meleças train station'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q10275778'), ('sName', 'Monte Real train station'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q18482642'), ('sName', 'Carriço halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q18482848'), ('sName', 'Feliteira halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q18482932'), ('sName', 'Guia halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q19702819'), ('sName', 'Monte Redondo halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q19702893'), ('sName', 'Zibreira halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q5552454'), ('sName', 'Dois Porto train station'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q8840980'), ('sName', 'Louriçal train station'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q18483271'), ('sName', 'Regueira de Pontes halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q8841573'), ('sName', 'Ramalhal train station'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q8842080'), ('sName', 'Torres Vedras train station'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q18483280'), ('sName', 'Ribeira de Seiça halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q19702853'), ('sName', 'Runa halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q18483456'), ('sName', 'São Mamede halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q38780585'), ('sName', 'First Minister of British Honduras'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q1643555'), ('oName', 'British Honduras')]
# [('s', 'http://www.wikidata.org/entity/Q26691790'), ('sName', 'mayor of Sant Pere Sallavinera'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q15967'), ('oName', 'Sant Pere Sallavinera')]
# [('s', 'http://www.wikidata.org/entity/Q105998262'), ('sName', 'Mayor of Star City'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q1419655'), ('oName', 'Star City')]
# [('s', 'http://www.wikidata.org/entity/Q108080825'), ('sName', 'Attorney-General of British Honduras'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q1643555'), ('oName', 'British Honduras')]
# [('s', 'http://www.wikidata.org/entity/Q26691184'), ('sName', 'mayor of Ripollet'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q13933'), ('oName', 'Ripollet')]
# [('s', 'http://www.wikidata.org/entity/Q56438477'), ('sName', 'mayor of Itano'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q1350904'), ('oName', 'Itano')]
# [('s', 'http://www.wikidata.org/entity/Q59773367'), ('sName', 'Arbúcies city councillor'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q13010'), ('oName', 'Arbúcies')]
# [('s', 'http://www.wikidata.org/entity/Q11907924'), ('sName', 'Flag of Ripollet'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q13933'), ('oName', 'Ripollet')]
# [('s', 'http://www.wikidata.org/entity/Q105514924'), ('sName', 'Ripollet results in 2021 Catalan parliamentary election'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q13933'), ('oName', 'Ripollet')]
# [('s', 'http://www.wikidata.org/entity/Q26695213'), ('sName', 'mayor of Pedreguer'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q1750923'), ('oName', 'Pedreguer')]
# [('s', 'http://www.wikidata.org/entity/Q44952776'), ('sName', 'Catalan regional election 2015 in Sant Pere Sallavinera'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q15967'), ('oName', 'Sant Pere Sallavinera')]
# [('s', 'http://www.wikidata.org/entity/Q101978391'), ('sName', 'Regional Regulation of Melawi Regency Number 04 Year 2018'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q14162'), ('oName', 'Melawi')]
# [('s', 'http://www.wikidata.org/entity/Q11481685'), ('sName', 'Hitachi Kokubunji'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q1055353'), ('oName', 'Hitachi Province')]
# [('s', 'http://www.wikidata.org/entity/Q26691392'), ('sName', 'mayor of Zalduendo de Álava'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q1443609'), ('oName', 'Zalduondo')]
# [('s', 'http://www.wikidata.org/entity/Q26695389'), ('sName', 'mayor of Cehegín'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q1757489'), ('oName', 'Cehegín')]
# [('s', 'http://www.wikidata.org/entity/Q62051046'), ('sName', 'Legislative Assembly of British Honduras'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q1643555'), ('oName', 'British Honduras')]
# [('s', 'http://www.wikidata.org/entity/Q26690765'), ('sName', 'mayor of Arbúcies'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q13010'), ('oName', 'Arbúcies')]
# [('s', 'http://www.wikidata.org/entity/Q105515175'), ('sName', 'Arbúcies results in 2021 Catalan parliamentary election'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q13010'), ('oName', 'Arbúcies')]
# [('s', 'http://www.wikidata.org/entity/Q44914898'), ('sName', 'Catalan regional election 2015 in Ripollet'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q13933'), ('oName', 'Ripollet')]
# [('s', 'http://www.wikidata.org/entity/Q45023173'), ('sName', 'Catalan regional election 2015 in Arbúcies'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q13010'), ('oName', 'Arbúcies')]
# [('s', 'http://www.wikidata.org/entity/Q56402053'), ('sName', 'Flag of Sant Pere Sallavinera'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q15967'), ('oName', 'Sant Pere Sallavinera')]
# [('s', 'http://www.wikidata.org/entity/Q56437866'), ('sName', 'mayor of Toyoyama'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q1345562'), ('oName', 'Toyoyama')]
# [('s', 'http://www.wikidata.org/entity/Q105514933'), ('sName', 'Sant Pere Sallavinera results in 2021 Catalan parliamentary election'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q15967'), ('oName', 'Sant Pere Sallavinera')]
# [('s', 'http://www.wikidata.org/entity/Q105482504'), ('sName', 'Arbúcies results in 2017 Catalan parliamentary election'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q13010'), ('oName', 'Arbúcies')]
# [('s', 'http://www.wikidata.org/entity/Q105482709'), ('sName', 'Ripollet results in 2017 Catalan parliamentary election'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q13933'), ('oName', 'Ripollet')]
# [('s', 'http://www.wikidata.org/entity/Q11481689'), ('sName', 'Hitachinokuni Sōshagū'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q1055353'), ('oName', 'Hitachi Province')]
# [('s', 'http://www.wikidata.org/entity/Q105481195'), ('sName', 'Sant Pere Sallavinera results in 2017 Catalan parliamentary election'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q15967'), ('oName', 'Sant Pere Sallavinera')]
# [('s', 'http://www.wikidata.org/entity/Q19294986'), ('sName', 'Louis Berlioz'), ('p', 'http://www.wikidata.org/prop/direct/P101'), ('pName', 'field of work'), ('o', 'http://www.wikidata.org/entity/Q121713'), ('oName', 'acupuncture')]
# [('s', 'http://www.wikidata.org/entity/Q64392269'), ('sName', 'Ian Gough'), ('p', 'http://www.wikidata.org/prop/direct/P101'), ('pName', 'field of work'), ('o', 'http://www.wikidata.org/entity/Q11497309'), ('oName', 'economic support')]
# [('s', 'http://www.wikidata.org/entity/Q19957642'), ('sName', 'Ruby Duncan'), ('p', 'http://www.wikidata.org/prop/direct/P101'), ('pName', 'field of work'), ('o', 'http://www.wikidata.org/entity/Q11497309'), ('oName', 'economic support')]
# [('s', 'http://www.wikidata.org/entity/Q81425306'), ('sName', 'Physiotherapy Douma'), ('p', 'http://www.wikidata.org/prop/direct/P101'), ('pName', 'field of work'), ('o', 'http://www.wikidata.org/entity/Q121713'), ('oName', 'acupuncture')]
# [('s', 'http://www.wikidata.org/entity/Q15809258'), ('sName', 'Healer of Berne'), ('p', 'http://www.wikidata.org/prop/direct/P101'), ('pName', 'field of work'), ('o', 'http://www.wikidata.org/entity/Q121713'), ('oName', 'acupuncture')]
# [('s', 'http://www.wikidata.org/entity/Q66535461'), ('sName', 'Emmanuel Kreike'), ('p', 'http://www.wikidata.org/prop/direct/P101'), ('pName', 'field of work'), ('o', 'http://www.wikidata.org/entity/Q11497309'), ('oName', 'economic support')]
# [('s', 'http://www.wikidata.org/entity/Q6066216'), ('sName', 'Ira Rubinoff'), ('p', 'http://www.wikidata.org/prop/direct/P101'), ('pName', 'field of work'), ('o', 'http://www.wikidata.org/entity/Q1673980'), ('oName', 'Smithsonian Tropical Research Institute')]
# [('s', 'http://www.wikidata.org/entity/Q55600270'), ('sName', 'Élise Boghossian'), ('p', 'http://www.wikidata.org/prop/direct/P101'), ('pName', 'field of work'), ('o', 'http://www.wikidata.org/entity/Q121713'), ('oName', 'acupuncture')]
# [('s', 'http://www.wikidata.org/entity/Q9044036'), ('sName', 'Su Yu-chang'), ('p', 'http://www.wikidata.org/prop/direct/P101'), ('pName', 'field of work'), ('o', 'http://www.wikidata.org/entity/Q121713'), ('oName', 'acupuncture')]
# [('s', 'http://www.wikidata.org/entity/Q17107163'), ('sName', 'Vilhelm Schjelderup'), ('p', 'http://www.wikidata.org/prop/direct/P101'), ('pName', 'field of work'), ('o', 'http://www.wikidata.org/entity/Q121713'), ('oName', 'acupuncture')]
# [('s', 'http://www.wikidata.org/entity/Q97147261'), ('sName', 'Clinics Dr. Erler'), ('p', 'http://www.wikidata.org/prop/direct/P101'), ('pName', 'field of work'), ('o', 'http://www.wikidata.org/entity/Q121713'), ('oName', 'acupuncture')]
# [('s', 'http://www.wikidata.org/entity/Q64175666'), ('sName', 'Jeremy Ross'), ('p', 'http://www.wikidata.org/prop/direct/P101'), ('pName', 'field of work'), ('o', 'http://www.wikidata.org/entity/Q121713'), ('oName', 'acupuncture')]
# [('s', 'http://www.wikidata.org/entity/Q96579961'), ('sName', 'Sana Clinic Nuremberg'), ('p', 'http://www.wikidata.org/prop/direct/P101'), ('pName', 'field of work'), ('o', 'http://www.wikidata.org/entity/Q121713'), ('oName', 'acupuncture')]
# [('s', 'http://www.wikidata.org/entity/Q47544113'), ('sName', 'Maesiah Thabane'), ('p', 'http://www.wikidata.org/prop/direct/P102'), ('pName', 'member of political party'), ('o', 'http://www.wikidata.org/entity/Q1346132'), ('oName', 'All Basotho Convention')]
# [('s', 'http://www.wikidata.org/entity/Q9092970'), ('sName', 'Vera Grabe'), ('p', 'http://www.wikidata.org/prop/direct/P102'), ('pName', 'member of political party'), ('o', 'http://www.wikidata.org/entity/Q1789014'), ('oName', '19th of April Movement')]
# [('s', 'http://www.wikidata.org/entity/Q5992796'), ('sName', 'Ignatius Shixwameni'), ('p', 'http://www.wikidata.org/prop/direct/P102'), ('pName', 'member of political party'), ('o', 'http://www.wikidata.org/entity/Q1129391'), ('oName', "All People's Party")]
# [('s', 'http://www.wikidata.org/entity/Q16194214'), ('sName', 'Mophato Monyake'), ('p', 'http://www.wikidata.org/prop/direct/P102'), ('pName', 'member of political party'), ('o', 'http://www.wikidata.org/entity/Q1346132'), ('oName', 'All Basotho Convention')]
# [('s', 'http://www.wikidata.org/entity/Q3660117'), ('sName', 'Carlos Pizarro Leongómez'), ('p', 'http://www.wikidata.org/prop/direct/P102'), ('pName', 'member of political party'), ('o', 'http://www.wikidata.org/entity/Q1789014'), ('oName', '19th of April Movement')]
# [('s', 'http://www.wikidata.org/entity/Q1567660'), ('sName', 'Hae Phoofolo'), ('p', 'http://www.wikidata.org/prop/direct/P102'), ('pName', 'member of political party'), ('o', 'http://www.wikidata.org/entity/Q1346132'), ('oName', 'All Basotho Convention')]
# [('s', 'http://www.wikidata.org/entity/Q4752142'), ('sName', 'Anatol Arhire'), ('p', 'http://www.wikidata.org/prop/direct/P102'), ('pName', 'member of political party'), ('o', 'http://www.wikidata.org/entity/Q1280031'), ('oName', 'Alliance for European Integration')]
# 100

# %%
# Consider the tennis players born after 1975, return who won more Grand Slams and cut the result to the top-10 (the result set must be a list of triples player IRI, label and #victories).
# Q1426 = Roger Federer
# wdt:P1344 (participant in)
# wdt:P2522 (victory)
#[('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('o', 'http://www.wikidata.org/entity/P569'), ('oName', 'date of birth')]
# 1) getting winners dob 

queryString = """

SELECT DISTINCT ?s ?sName ?p ?pName ?o ?oName
WHERE {
   # ?s ?p ?o.
   # ?s sc:name ?sName.
   # ?p sc:name ?pName.
   # ?o sc:name ?oName.
   
   
   # today filter with regex not working
   FILTER (REGEX(?pName,"year","i"))
   
   #it never returns the result if un-comment the filter
   #FILTER (?p not in (wdt:P2922, wdt:P991))
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('s', 'http://www.wikidata.org/entity/Q95452024'), ('sName', 'Template:Vice Presidents of the Maldives'), ('p', 'http://www.wikidata.org/prop/direct/P1423'), ('pName', 'template has topic'), ('o', 'http://www.wikidata.org/entity/Q10999435'), ('oName', 'Vice President of the Maldives')]
# [('s', 'http://www.wikidata.org/entity/Q25752552'), ('sName', 'Template:2001 in Europe'), ('p', 'http://www.wikidata.org/prop/direct/P1423'), ('pName', 'template has topic'), ('o', 'http://www.wikidata.org/entity/Q17111750'), ('oName', '2001 in Europe')]
# [('s', 'http://www.wikidata.org/entity/Q6675314'), ('sName', 'Template:Alcest'), ('p', 'http://www.wikidata.org/prop/direct/P1423'), ('pName', 'template has topic'), ('o', 'http://www.wikidata.org/entity/Q1517060'), ('oName', 'Alcest')]
# [('s', 'http://www.wikidata.org/entity/Q22785857'), ('sName', 'Template:2006 in Europe'), ('p', 'http://www.wikidata.org/prop/direct/P1423'), ('pName', 'template has topic'), ('o', 'http://www.wikidata.org/entity/Q17111782'), ('oName', '2006 in Europe')]
# [('s', 'http://www.wikidata.org/entity/Q85816744'), ('sName', 'Yodli'), ('p', 'http://www.wikidata.org/prop/direct/P1268'), ('pName', 'represents'), ('o', 'http://www.wikidata.org/entity/Q1053559'), ('oName', '2020 Winter Youth Olympics')]
# [('s', 'http://www.wikidata.org/entity/Q1064606'), ('sName', 'President of the Maldives'), ('p', 'http://www.wikidata.org/prop/direct/P2098'), ('pName', 'substitute/deputy/replacement of office/officeholder'), ('o', 'http://www.wikidata.org/entity/Q10999435'), ('oName', 'Vice President of the Maldives')]
# [('s', 'http://www.wikidata.org/entity/Q10275776'), ('sName', 'Estação Ferroviária de Mafra'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q18483474'), ('sName', 'Telhada halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q8202323'), ('sName', 'Alcainça-Moinhos halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q8202353'), ('sName', 'Bicanho Halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q8779275'), ('sName', 'Amieira train station'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q8841005'), ('sName', 'Malveira train station'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q17267254'), ('sName', 'Fanhais halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q17267315'), ('sName', 'Cela halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q8779401'), ('sName', 'Bombarral train station'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q8840924'), ('sName', 'Leiria train station'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q8841025'), ('sName', 'Marinha Grande station'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q8841035'), ('sName', 'Martingança train station'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q8841427'), ('sName', 'Pataias train station'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q8842140'), ('sName', 'Valado train station'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q248226'), ('sName', 'Agualva-Cacém railway station'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q18482873'), ('sName', 'Fontela halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q18482882'), ('sName', 'Fontela-A halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q18482941'), ('sName', 'Jerumelo halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q18483298'), ('sName', 'Salir do Porto halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q18483365'), ('sName', 'Sapataria Halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q800752'), ('sName', 'Figueira da Foz train station'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q8841452'), ('sName', 'Pero Negro train station'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q8841387'), ('sName', 'Outeiro train station'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q10275790'), ('sName', 'Sabugo train station'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q16781965'), ('sName', 'Pedra Furada halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q16781966'), ('sName', 'Telhal halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q17000336'), ('sName', 'Óbidos halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q587866'), ('sName', 'Estação Ferroviária de Caldas da Rainha'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q18482975'), ('sName', 'Lares halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q557982'), ('sName', 'Bifurcação de Lares train station'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q10275797'), ('sName', 'São Martinho do Porto train station'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q18482831'), ('sName', 'Famalicão da Nazaré halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q8841053'), ('sName', 'Mira Sintra-Meleças train station'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q10275778'), ('sName', 'Monte Real train station'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q18482642'), ('sName', 'Carriço halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q18482848'), ('sName', 'Feliteira halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q18482932'), ('sName', 'Guia halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q19702819'), ('sName', 'Monte Redondo halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q19702893'), ('sName', 'Zibreira halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q5552454'), ('sName', 'Dois Porto train station'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q8840980'), ('sName', 'Louriçal train station'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q18483271'), ('sName', 'Regueira de Pontes halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q8841573'), ('sName', 'Ramalhal train station'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q8842080'), ('sName', 'Torres Vedras train station'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q18483280'), ('sName', 'Ribeira de Seiça halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q19702853'), ('sName', 'Runa halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q18483456'), ('sName', 'São Mamede halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q38780585'), ('sName', 'First Minister of British Honduras'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q1643555'), ('oName', 'British Honduras')]
# [('s', 'http://www.wikidata.org/entity/Q26691790'), ('sName', 'mayor of Sant Pere Sallavinera'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q15967'), ('oName', 'Sant Pere Sallavinera')]
# [('s', 'http://www.wikidata.org/entity/Q105998262'), ('sName', 'Mayor of Star City'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q1419655'), ('oName', 'Star City')]
# [('s', 'http://www.wikidata.org/entity/Q108080825'), ('sName', 'Attorney-General of British Honduras'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q1643555'), ('oName', 'British Honduras')]
# [('s', 'http://www.wikidata.org/entity/Q26691184'), ('sName', 'mayor of Ripollet'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q13933'), ('oName', 'Ripollet')]
# [('s', 'http://www.wikidata.org/entity/Q56438477'), ('sName', 'mayor of Itano'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q1350904'), ('oName', 'Itano')]
# [('s', 'http://www.wikidata.org/entity/Q59773367'), ('sName', 'Arbúcies city councillor'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q13010'), ('oName', 'Arbúcies')]
# [('s', 'http://www.wikidata.org/entity/Q11907924'), ('sName', 'Flag of Ripollet'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q13933'), ('oName', 'Ripollet')]
# [('s', 'http://www.wikidata.org/entity/Q105514924'), ('sName', 'Ripollet results in 2021 Catalan parliamentary election'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q13933'), ('oName', 'Ripollet')]
# [('s', 'http://www.wikidata.org/entity/Q26695213'), ('sName', 'mayor of Pedreguer'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q1750923'), ('oName', 'Pedreguer')]
# [('s', 'http://www.wikidata.org/entity/Q44952776'), ('sName', 'Catalan regional election 2015 in Sant Pere Sallavinera'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q15967'), ('oName', 'Sant Pere Sallavinera')]
# [('s', 'http://www.wikidata.org/entity/Q101978391'), ('sName', 'Regional Regulation of Melawi Regency Number 04 Year 2018'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q14162'), ('oName', 'Melawi')]
# [('s', 'http://www.wikidata.org/entity/Q11481685'), ('sName', 'Hitachi Kokubunji'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q1055353'), ('oName', 'Hitachi Province')]
# [('s', 'http://www.wikidata.org/entity/Q26691392'), ('sName', 'mayor of Zalduendo de Álava'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q1443609'), ('oName', 'Zalduondo')]
# [('s', 'http://www.wikidata.org/entity/Q26695389'), ('sName', 'mayor of Cehegín'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q1757489'), ('oName', 'Cehegín')]
# [('s', 'http://www.wikidata.org/entity/Q62051046'), ('sName', 'Legislative Assembly of British Honduras'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q1643555'), ('oName', 'British Honduras')]
# [('s', 'http://www.wikidata.org/entity/Q26690765'), ('sName', 'mayor of Arbúcies'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q13010'), ('oName', 'Arbúcies')]
# [('s', 'http://www.wikidata.org/entity/Q105515175'), ('sName', 'Arbúcies results in 2021 Catalan parliamentary election'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q13010'), ('oName', 'Arbúcies')]
# [('s', 'http://www.wikidata.org/entity/Q44914898'), ('sName', 'Catalan regional election 2015 in Ripollet'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q13933'), ('oName', 'Ripollet')]
# [('s', 'http://www.wikidata.org/entity/Q45023173'), ('sName', 'Catalan regional election 2015 in Arbúcies'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q13010'), ('oName', 'Arbúcies')]
# [('s', 'http://www.wikidata.org/entity/Q56402053'), ('sName', 'Flag of Sant Pere Sallavinera'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q15967'), ('oName', 'Sant Pere Sallavinera')]
# [('s', 'http://www.wikidata.org/entity/Q56437866'), ('sName', 'mayor of Toyoyama'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q1345562'), ('oName', 'Toyoyama')]
# [('s', 'http://www.wikidata.org/entity/Q105514933'), ('sName', 'Sant Pere Sallavinera results in 2021 Catalan parliamentary election'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q15967'), ('oName', 'Sant Pere Sallavinera')]
# [('s', 'http://www.wikidata.org/entity/Q105482504'), ('sName', 'Arbúcies results in 2017 Catalan parliamentary election'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q13010'), ('oName', 'Arbúcies')]
# [('s', 'http://www.wikidata.org/entity/Q105482709'), ('sName', 'Ripollet results in 2017 Catalan parliamentary election'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q13933'), ('oName', 'Ripollet')]
# [('s', 'http://www.wikidata.org/entity/Q11481689'), ('sName', 'Hitachinokuni Sōshagū'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q1055353'), ('oName', 'Hitachi Province')]
# [('s', 'http://www.wikidata.org/entity/Q105481195'), ('sName', 'Sant Pere Sallavinera results in 2017 Catalan parliamentary election'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q15967'), ('oName', 'Sant Pere Sallavinera')]
# [('s', 'http://www.wikidata.org/entity/Q19294986'), ('sName', 'Louis Berlioz'), ('p', 'http://www.wikidata.org/prop/direct/P101'), ('pName', 'field of work'), ('o', 'http://www.wikidata.org/entity/Q121713'), ('oName', 'acupuncture')]
# [('s', 'http://www.wikidata.org/entity/Q64392269'), ('sName', 'Ian Gough'), ('p', 'http://www.wikidata.org/prop/direct/P101'), ('pName', 'field of work'), ('o', 'http://www.wikidata.org/entity/Q11497309'), ('oName', 'economic support')]
# [('s', 'http://www.wikidata.org/entity/Q19957642'), ('sName', 'Ruby Duncan'), ('p', 'http://www.wikidata.org/prop/direct/P101'), ('pName', 'field of work'), ('o', 'http://www.wikidata.org/entity/Q11497309'), ('oName', 'economic support')]
# [('s', 'http://www.wikidata.org/entity/Q81425306'), ('sName', 'Physiotherapy Douma'), ('p', 'http://www.wikidata.org/prop/direct/P101'), ('pName', 'field of work'), ('o', 'http://www.wikidata.org/entity/Q121713'), ('oName', 'acupuncture')]
# [('s', 'http://www.wikidata.org/entity/Q15809258'), ('sName', 'Healer of Berne'), ('p', 'http://www.wikidata.org/prop/direct/P101'), ('pName', 'field of work'), ('o', 'http://www.wikidata.org/entity/Q121713'), ('oName', 'acupuncture')]
# [('s', 'http://www.wikidata.org/entity/Q66535461'), ('sName', 'Emmanuel Kreike'), ('p', 'http://www.wikidata.org/prop/direct/P101'), ('pName', 'field of work'), ('o', 'http://www.wikidata.org/entity/Q11497309'), ('oName', 'economic support')]
# [('s', 'http://www.wikidata.org/entity/Q6066216'), ('sName', 'Ira Rubinoff'), ('p', 'http://www.wikidata.org/prop/direct/P101'), ('pName', 'field of work'), ('o', 'http://www.wikidata.org/entity/Q1673980'), ('oName', 'Smithsonian Tropical Research Institute')]
# [('s', 'http://www.wikidata.org/entity/Q55600270'), ('sName', 'Élise Boghossian'), ('p', 'http://www.wikidata.org/prop/direct/P101'), ('pName', 'field of work'), ('o', 'http://www.wikidata.org/entity/Q121713'), ('oName', 'acupuncture')]
# [('s', 'http://www.wikidata.org/entity/Q9044036'), ('sName', 'Su Yu-chang'), ('p', 'http://www.wikidata.org/prop/direct/P101'), ('pName', 'field of work'), ('o', 'http://www.wikidata.org/entity/Q121713'), ('oName', 'acupuncture')]
# [('s', 'http://www.wikidata.org/entity/Q17107163'), ('sName', 'Vilhelm Schjelderup'), ('p', 'http://www.wikidata.org/prop/direct/P101'), ('pName', 'field of work'), ('o', 'http://www.wikidata.org/entity/Q121713'), ('oName', 'acupuncture')]
# [('s', 'http://www.wikidata.org/entity/Q97147261'), ('sName', 'Clinics Dr. Erler'), ('p', 'http://www.wikidata.org/prop/direct/P101'), ('pName', 'field of work'), ('o', 'http://www.wikidata.org/entity/Q121713'), ('oName', 'acupuncture')]
# [('s', 'http://www.wikidata.org/entity/Q64175666'), ('sName', 'Jeremy Ross'), ('p', 'http://www.wikidata.org/prop/direct/P101'), ('pName', 'field of work'), ('o', 'http://www.wikidata.org/entity/Q121713'), ('oName', 'acupuncture')]
# [('s', 'http://www.wikidata.org/entity/Q96579961'), ('sName', 'Sana Clinic Nuremberg'), ('p', 'http://www.wikidata.org/prop/direct/P101'), ('pName', 'field of work'), ('o', 'http://www.wikidata.org/entity/Q121713'), ('oName', 'acupuncture')]
# [('s', 'http://www.wikidata.org/entity/Q47544113'), ('sName', 'Maesiah Thabane'), ('p', 'http://www.wikidata.org/prop/direct/P102'), ('pName', 'member of political party'), ('o', 'http://www.wikidata.org/entity/Q1346132'), ('oName', 'All Basotho Convention')]
# [('s', 'http://www.wikidata.org/entity/Q9092970'), ('sName', 'Vera Grabe'), ('p', 'http://www.wikidata.org/prop/direct/P102'), ('pName', 'member of political party'), ('o', 'http://www.wikidata.org/entity/Q1789014'), ('oName', '19th of April Movement')]
# [('s', 'http://www.wikidata.org/entity/Q5992796'), ('sName', 'Ignatius Shixwameni'), ('p', 'http://www.wikidata.org/prop/direct/P102'), ('pName', 'member of political party'), ('o', 'http://www.wikidata.org/entity/Q1129391'), ('oName', "All People's Party")]
# [('s', 'http://www.wikidata.org/entity/Q16194214'), ('sName', 'Mophato Monyake'), ('p', 'http://www.wikidata.org/prop/direct/P102'), ('pName', 'member of political party'), ('o', 'http://www.wikidata.org/entity/Q1346132'), ('oName', 'All Basotho Convention')]
# [('s', 'http://www.wikidata.org/entity/Q3660117'), ('sName', 'Carlos Pizarro Leongómez'), ('p', 'http://www.wikidata.org/prop/direct/P102'), ('pName', 'member of political party'), ('o', 'http://www.wikidata.org/entity/Q1789014'), ('oName', '19th of April Movement')]
# [('s', 'http://www.wikidata.org/entity/Q1567660'), ('sName', 'Hae Phoofolo'), ('p', 'http://www.wikidata.org/prop/direct/P102'), ('pName', 'member of political party'), ('o', 'http://www.wikidata.org/entity/Q1346132'), ('oName', 'All Basotho Convention')]
# [('s', 'http://www.wikidata.org/entity/Q4752142'), ('sName', 'Anatol Arhire'), ('p', 'http://www.wikidata.org/prop/direct/P102'), ('pName', 'member of political party'), ('o', 'http://www.wikidata.org/entity/Q1280031'), ('oName', 'Alliance for European Integration')]
# 100

# %%
# Consider the tennis players born after 1975, return who won more Grand Slams and cut the result to the top-10 (the result set must be a list of triples player IRI, label and #victories).
# Q1426 = Roger Federer
# wdt:P1344 (participant in)
# wdt:P2522 (victory)
#[('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('o', 'http://www.wikidata.org/entity/P569'), ('oName', 'date of birth')]
# 1) getting winners dob 

queryString = """

SELECT DISTINCT ?s ?sName ?p ?pName ?o ?oName
WHERE {
   # ?s ?p ?o.
   # ?s sc:name ?sName.
   # ?p sc:name ?pName.
   # ?o sc:name ?oName.
   
   
   #today filter with regex not working
   FILTER (REGEX(?pName,"year","i"))
   
   #it never returns the result if un-comment the filter
   #FILTER (?p not in (wdt:P2922, wdt:P837))
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('s', 'http://www.wikidata.org/entity/Q95452024'), ('sName', 'Template:Vice Presidents of the Maldives'), ('p', 'http://www.wikidata.org/prop/direct/P1423'), ('pName', 'template has topic'), ('o', 'http://www.wikidata.org/entity/Q10999435'), ('oName', 'Vice President of the Maldives')]
# [('s', 'http://www.wikidata.org/entity/Q25752552'), ('sName', 'Template:2001 in Europe'), ('p', 'http://www.wikidata.org/prop/direct/P1423'), ('pName', 'template has topic'), ('o', 'http://www.wikidata.org/entity/Q17111750'), ('oName', '2001 in Europe')]
# [('s', 'http://www.wikidata.org/entity/Q6675314'), ('sName', 'Template:Alcest'), ('p', 'http://www.wikidata.org/prop/direct/P1423'), ('pName', 'template has topic'), ('o', 'http://www.wikidata.org/entity/Q1517060'), ('oName', 'Alcest')]
# [('s', 'http://www.wikidata.org/entity/Q22785857'), ('sName', 'Template:2006 in Europe'), ('p', 'http://www.wikidata.org/prop/direct/P1423'), ('pName', 'template has topic'), ('o', 'http://www.wikidata.org/entity/Q17111782'), ('oName', '2006 in Europe')]
# [('s', 'http://www.wikidata.org/entity/Q85816744'), ('sName', 'Yodli'), ('p', 'http://www.wikidata.org/prop/direct/P1268'), ('pName', 'represents'), ('o', 'http://www.wikidata.org/entity/Q1053559'), ('oName', '2020 Winter Youth Olympics')]
# [('s', 'http://www.wikidata.org/entity/Q1064606'), ('sName', 'President of the Maldives'), ('p', 'http://www.wikidata.org/prop/direct/P2098'), ('pName', 'substitute/deputy/replacement of office/officeholder'), ('o', 'http://www.wikidata.org/entity/Q10999435'), ('oName', 'Vice President of the Maldives')]
# [('s', 'http://www.wikidata.org/entity/Q10275776'), ('sName', 'Estação Ferroviária de Mafra'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q18483474'), ('sName', 'Telhada halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q8202323'), ('sName', 'Alcainça-Moinhos halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q8202353'), ('sName', 'Bicanho Halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q8779275'), ('sName', 'Amieira train station'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q8841005'), ('sName', 'Malveira train station'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q17267254'), ('sName', 'Fanhais halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q17267315'), ('sName', 'Cela halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q8779401'), ('sName', 'Bombarral train station'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q8840924'), ('sName', 'Leiria train station'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q8841025'), ('sName', 'Marinha Grande station'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q8841035'), ('sName', 'Martingança train station'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q8841427'), ('sName', 'Pataias train station'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q8842140'), ('sName', 'Valado train station'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q248226'), ('sName', 'Agualva-Cacém railway station'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q18482873'), ('sName', 'Fontela halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q18482882'), ('sName', 'Fontela-A halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q18482941'), ('sName', 'Jerumelo halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q18483298'), ('sName', 'Salir do Porto halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q18483365'), ('sName', 'Sapataria Halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q800752'), ('sName', 'Figueira da Foz train station'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q8841452'), ('sName', 'Pero Negro train station'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q8841387'), ('sName', 'Outeiro train station'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q10275790'), ('sName', 'Sabugo train station'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q16781965'), ('sName', 'Pedra Furada halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q16781966'), ('sName', 'Telhal halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q17000336'), ('sName', 'Óbidos halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q587866'), ('sName', 'Estação Ferroviária de Caldas da Rainha'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q18482975'), ('sName', 'Lares halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q557982'), ('sName', 'Bifurcação de Lares train station'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q10275797'), ('sName', 'São Martinho do Porto train station'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q18482831'), ('sName', 'Famalicão da Nazaré halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q8841053'), ('sName', 'Mira Sintra-Meleças train station'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q10275778'), ('sName', 'Monte Real train station'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q18482642'), ('sName', 'Carriço halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q18482848'), ('sName', 'Feliteira halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q18482932'), ('sName', 'Guia halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q19702819'), ('sName', 'Monte Redondo halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q19702893'), ('sName', 'Zibreira halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q5552454'), ('sName', 'Dois Porto train station'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q8840980'), ('sName', 'Louriçal train station'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q18483271'), ('sName', 'Regueira de Pontes halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q8841573'), ('sName', 'Ramalhal train station'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q8842080'), ('sName', 'Torres Vedras train station'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q18483280'), ('sName', 'Ribeira de Seiça halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q19702853'), ('sName', 'Runa halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q18483456'), ('sName', 'São Mamede halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q38780585'), ('sName', 'First Minister of British Honduras'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q1643555'), ('oName', 'British Honduras')]
# [('s', 'http://www.wikidata.org/entity/Q26691790'), ('sName', 'mayor of Sant Pere Sallavinera'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q15967'), ('oName', 'Sant Pere Sallavinera')]
# [('s', 'http://www.wikidata.org/entity/Q105998262'), ('sName', 'Mayor of Star City'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q1419655'), ('oName', 'Star City')]
# [('s', 'http://www.wikidata.org/entity/Q108080825'), ('sName', 'Attorney-General of British Honduras'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q1643555'), ('oName', 'British Honduras')]
# [('s', 'http://www.wikidata.org/entity/Q26691184'), ('sName', 'mayor of Ripollet'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q13933'), ('oName', 'Ripollet')]
# [('s', 'http://www.wikidata.org/entity/Q56438477'), ('sName', 'mayor of Itano'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q1350904'), ('oName', 'Itano')]
# [('s', 'http://www.wikidata.org/entity/Q59773367'), ('sName', 'Arbúcies city councillor'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q13010'), ('oName', 'Arbúcies')]
# [('s', 'http://www.wikidata.org/entity/Q11907924'), ('sName', 'Flag of Ripollet'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q13933'), ('oName', 'Ripollet')]
# [('s', 'http://www.wikidata.org/entity/Q105514924'), ('sName', 'Ripollet results in 2021 Catalan parliamentary election'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q13933'), ('oName', 'Ripollet')]
# [('s', 'http://www.wikidata.org/entity/Q26695213'), ('sName', 'mayor of Pedreguer'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q1750923'), ('oName', 'Pedreguer')]
# [('s', 'http://www.wikidata.org/entity/Q44952776'), ('sName', 'Catalan regional election 2015 in Sant Pere Sallavinera'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q15967'), ('oName', 'Sant Pere Sallavinera')]
# [('s', 'http://www.wikidata.org/entity/Q101978391'), ('sName', 'Regional Regulation of Melawi Regency Number 04 Year 2018'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q14162'), ('oName', 'Melawi')]
# [('s', 'http://www.wikidata.org/entity/Q11481685'), ('sName', 'Hitachi Kokubunji'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q1055353'), ('oName', 'Hitachi Province')]
# [('s', 'http://www.wikidata.org/entity/Q26691392'), ('sName', 'mayor of Zalduendo de Álava'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q1443609'), ('oName', 'Zalduondo')]
# [('s', 'http://www.wikidata.org/entity/Q26695389'), ('sName', 'mayor of Cehegín'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q1757489'), ('oName', 'Cehegín')]
# [('s', 'http://www.wikidata.org/entity/Q62051046'), ('sName', 'Legislative Assembly of British Honduras'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q1643555'), ('oName', 'British Honduras')]
# [('s', 'http://www.wikidata.org/entity/Q26690765'), ('sName', 'mayor of Arbúcies'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q13010'), ('oName', 'Arbúcies')]
# [('s', 'http://www.wikidata.org/entity/Q105515175'), ('sName', 'Arbúcies results in 2021 Catalan parliamentary election'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q13010'), ('oName', 'Arbúcies')]
# [('s', 'http://www.wikidata.org/entity/Q44914898'), ('sName', 'Catalan regional election 2015 in Ripollet'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q13933'), ('oName', 'Ripollet')]
# [('s', 'http://www.wikidata.org/entity/Q45023173'), ('sName', 'Catalan regional election 2015 in Arbúcies'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q13010'), ('oName', 'Arbúcies')]
# [('s', 'http://www.wikidata.org/entity/Q56402053'), ('sName', 'Flag of Sant Pere Sallavinera'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q15967'), ('oName', 'Sant Pere Sallavinera')]
# [('s', 'http://www.wikidata.org/entity/Q56437866'), ('sName', 'mayor of Toyoyama'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q1345562'), ('oName', 'Toyoyama')]
# [('s', 'http://www.wikidata.org/entity/Q105514933'), ('sName', 'Sant Pere Sallavinera results in 2021 Catalan parliamentary election'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q15967'), ('oName', 'Sant Pere Sallavinera')]
# [('s', 'http://www.wikidata.org/entity/Q105482504'), ('sName', 'Arbúcies results in 2017 Catalan parliamentary election'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q13010'), ('oName', 'Arbúcies')]
# [('s', 'http://www.wikidata.org/entity/Q105482709'), ('sName', 'Ripollet results in 2017 Catalan parliamentary election'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q13933'), ('oName', 'Ripollet')]
# [('s', 'http://www.wikidata.org/entity/Q11481689'), ('sName', 'Hitachinokuni Sōshagū'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q1055353'), ('oName', 'Hitachi Province')]
# [('s', 'http://www.wikidata.org/entity/Q105481195'), ('sName', 'Sant Pere Sallavinera results in 2017 Catalan parliamentary election'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q15967'), ('oName', 'Sant Pere Sallavinera')]
# [('s', 'http://www.wikidata.org/entity/Q19294986'), ('sName', 'Louis Berlioz'), ('p', 'http://www.wikidata.org/prop/direct/P101'), ('pName', 'field of work'), ('o', 'http://www.wikidata.org/entity/Q121713'), ('oName', 'acupuncture')]
# [('s', 'http://www.wikidata.org/entity/Q64392269'), ('sName', 'Ian Gough'), ('p', 'http://www.wikidata.org/prop/direct/P101'), ('pName', 'field of work'), ('o', 'http://www.wikidata.org/entity/Q11497309'), ('oName', 'economic support')]
# [('s', 'http://www.wikidata.org/entity/Q19957642'), ('sName', 'Ruby Duncan'), ('p', 'http://www.wikidata.org/prop/direct/P101'), ('pName', 'field of work'), ('o', 'http://www.wikidata.org/entity/Q11497309'), ('oName', 'economic support')]
# [('s', 'http://www.wikidata.org/entity/Q81425306'), ('sName', 'Physiotherapy Douma'), ('p', 'http://www.wikidata.org/prop/direct/P101'), ('pName', 'field of work'), ('o', 'http://www.wikidata.org/entity/Q121713'), ('oName', 'acupuncture')]
# [('s', 'http://www.wikidata.org/entity/Q15809258'), ('sName', 'Healer of Berne'), ('p', 'http://www.wikidata.org/prop/direct/P101'), ('pName', 'field of work'), ('o', 'http://www.wikidata.org/entity/Q121713'), ('oName', 'acupuncture')]
# [('s', 'http://www.wikidata.org/entity/Q66535461'), ('sName', 'Emmanuel Kreike'), ('p', 'http://www.wikidata.org/prop/direct/P101'), ('pName', 'field of work'), ('o', 'http://www.wikidata.org/entity/Q11497309'), ('oName', 'economic support')]
# [('s', 'http://www.wikidata.org/entity/Q6066216'), ('sName', 'Ira Rubinoff'), ('p', 'http://www.wikidata.org/prop/direct/P101'), ('pName', 'field of work'), ('o', 'http://www.wikidata.org/entity/Q1673980'), ('oName', 'Smithsonian Tropical Research Institute')]
# [('s', 'http://www.wikidata.org/entity/Q55600270'), ('sName', 'Élise Boghossian'), ('p', 'http://www.wikidata.org/prop/direct/P101'), ('pName', 'field of work'), ('o', 'http://www.wikidata.org/entity/Q121713'), ('oName', 'acupuncture')]
# [('s', 'http://www.wikidata.org/entity/Q9044036'), ('sName', 'Su Yu-chang'), ('p', 'http://www.wikidata.org/prop/direct/P101'), ('pName', 'field of work'), ('o', 'http://www.wikidata.org/entity/Q121713'), ('oName', 'acupuncture')]
# [('s', 'http://www.wikidata.org/entity/Q17107163'), ('sName', 'Vilhelm Schjelderup'), ('p', 'http://www.wikidata.org/prop/direct/P101'), ('pName', 'field of work'), ('o', 'http://www.wikidata.org/entity/Q121713'), ('oName', 'acupuncture')]
# [('s', 'http://www.wikidata.org/entity/Q97147261'), ('sName', 'Clinics Dr. Erler'), ('p', 'http://www.wikidata.org/prop/direct/P101'), ('pName', 'field of work'), ('o', 'http://www.wikidata.org/entity/Q121713'), ('oName', 'acupuncture')]
# [('s', 'http://www.wikidata.org/entity/Q64175666'), ('sName', 'Jeremy Ross'), ('p', 'http://www.wikidata.org/prop/direct/P101'), ('pName', 'field of work'), ('o', 'http://www.wikidata.org/entity/Q121713'), ('oName', 'acupuncture')]
# [('s', 'http://www.wikidata.org/entity/Q96579961'), ('sName', 'Sana Clinic Nuremberg'), ('p', 'http://www.wikidata.org/prop/direct/P101'), ('pName', 'field of work'), ('o', 'http://www.wikidata.org/entity/Q121713'), ('oName', 'acupuncture')]
# [('s', 'http://www.wikidata.org/entity/Q47544113'), ('sName', 'Maesiah Thabane'), ('p', 'http://www.wikidata.org/prop/direct/P102'), ('pName', 'member of political party'), ('o', 'http://www.wikidata.org/entity/Q1346132'), ('oName', 'All Basotho Convention')]
# [('s', 'http://www.wikidata.org/entity/Q9092970'), ('sName', 'Vera Grabe'), ('p', 'http://www.wikidata.org/prop/direct/P102'), ('pName', 'member of political party'), ('o', 'http://www.wikidata.org/entity/Q1789014'), ('oName', '19th of April Movement')]
# [('s', 'http://www.wikidata.org/entity/Q5992796'), ('sName', 'Ignatius Shixwameni'), ('p', 'http://www.wikidata.org/prop/direct/P102'), ('pName', 'member of political party'), ('o', 'http://www.wikidata.org/entity/Q1129391'), ('oName', "All People's Party")]
# [('s', 'http://www.wikidata.org/entity/Q16194214'), ('sName', 'Mophato Monyake'), ('p', 'http://www.wikidata.org/prop/direct/P102'), ('pName', 'member of political party'), ('o', 'http://www.wikidata.org/entity/Q1346132'), ('oName', 'All Basotho Convention')]
# [('s', 'http://www.wikidata.org/entity/Q3660117'), ('sName', 'Carlos Pizarro Leongómez'), ('p', 'http://www.wikidata.org/prop/direct/P102'), ('pName', 'member of political party'), ('o', 'http://www.wikidata.org/entity/Q1789014'), ('oName', '19th of April Movement')]
# [('s', 'http://www.wikidata.org/entity/Q1567660'), ('sName', 'Hae Phoofolo'), ('p', 'http://www.wikidata.org/prop/direct/P102'), ('pName', 'member of political party'), ('o', 'http://www.wikidata.org/entity/Q1346132'), ('oName', 'All Basotho Convention')]
# [('s', 'http://www.wikidata.org/entity/Q4752142'), ('sName', 'Anatol Arhire'), ('p', 'http://www.wikidata.org/prop/direct/P102'), ('pName', 'member of political party'), ('o', 'http://www.wikidata.org/entity/Q1280031'), ('oName', 'Alliance for European Integration')]
# 100

# %%
# Consider the tennis players born after 1975, return who won more Grand Slams and cut the result to the top-10 (the result set must be a list of triples player IRI, label and #victories).
# Q1426 = Roger Federer
# wdt:P1344 (participant in)
# wdt:P2522 (victory)
#[('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('o', 'http://www.wikidata.org/entity/P569'), ('oName', 'date of birth')]
# 1) getting winners dob 

queryString = """

SELECT DISTINCT ?s ?sName ?p ?pName ?o ?oName
WHERE {
   # ?s ?p ?o.
   # ?s sc:name ?sName.
   # ?p sc:name ?pName.
   # ?o sc:name ?oName.
   
   # today filter with regex not working
   FILTER (REGEX(?pName,"birth","i"))
   FILTER (?p not in (wdt:P19, wdt:P837))
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('s', 'http://www.wikidata.org/entity/Q10275776'), ('sName', 'Estação Ferroviária de Mafra'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q11235194'), ('sName', 'Tokyo Solamachi'), ('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q11497641'), ('oName', 'Oshiage')]
# [('s', 'http://www.wikidata.org/entity/Q15628796'), ('sName', 'Pedro Ponce de Cabrera'), ('p', 'http://www.wikidata.org/prop/direct/P119'), ('pName', 'place of burial'), ('o', 'http://www.wikidata.org/entity/Q16608610'), ('oName', 'Monastery of Santa María de Nogales')]
# [('s', 'http://www.wikidata.org/entity/Q18483474'), ('sName', 'Telhada halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q18531652'), ('sName', 'William Walker'), ('p', 'http://www.wikidata.org/prop/direct/P1343'), ('pName', 'described by source'), ('o', 'http://www.wikidata.org/entity/Q17037575'), ('oName', 'Oxford Biography Index')]
# [('s', 'http://www.wikidata.org/entity/Q4829629'), ('sName', 'Awa-Ōmiya Station'), ('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q1350904'), ('oName', 'Itano')]
# [('s', 'http://www.wikidata.org/entity/Q7371392'), ('sName', 'Route 1'), ('p', 'http://www.wikidata.org/prop/direct/P126'), ('pName', 'maintained by'), ('o', 'http://www.wikidata.org/entity/Q11415304'), ('oName', 'Nagoya Expressway Public Corporation')]
# [('s', 'http://www.wikidata.org/entity/Q8134074'), ('sName', 'Sumida Aquarium'), ('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q11497641'), ('oName', 'Oshiage')]
# [('s', 'http://www.wikidata.org/entity/Q8146191'), ('sName', 'Nanga Pinoh'), ('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q14162'), ('oName', 'Melawi')]
# [('s', 'http://www.wikidata.org/entity/Q8167413'), ('sName', 'Guguak VIII Koto'), ('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q12403132'), ('oName', 'Guguak')]
# [('s', 'http://www.wikidata.org/entity/Q8183600'), ('sName', 'Agrostroj Pelhřimov'), ('p', 'http://www.wikidata.org/prop/direct/P127'), ('pName', 'owned by'), ('o', 'http://www.wikidata.org/entity/Q100343342'), ('oName', 'Lubomír Stoklásek')]
# [('s', 'http://www.wikidata.org/entity/Q8183671'), ('sName', 'Aarão de Lacerda'), ('p', 'http://www.wikidata.org/prop/direct/P108'), ('pName', 'employer'), ('o', 'http://www.wikidata.org/entity/Q10279508'), ('oName', 'Faculdade de Letras da Universidade de Coimbra')]
# [('s', 'http://www.wikidata.org/entity/Q8183671'), ('sName', 'Aarão de Lacerda'), ('p', 'http://www.wikidata.org/prop/direct/P108'), ('pName', 'employer'), ('o', 'http://www.wikidata.org/entity/Q10279509'), ('oName', 'Faculty of Arts and Humanities of the University of Porto')]
# [('s', 'http://www.wikidata.org/entity/Q8190594'), ('sName', 'Awa-Kawabata Station'), ('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q1350904'), ('oName', 'Itano')]
# [('s', 'http://www.wikidata.org/entity/Q8190673'), ('sName', 'Itano Station'), ('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q1350904'), ('oName', 'Itano')]
# [('s', 'http://www.wikidata.org/entity/Q8190939'), ('sName', 'Calaf-Salavinera Airport'), ('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q15967'), ('oName', 'Sant Pere Sallavinera')]
# [('s', 'http://www.wikidata.org/entity/Q8194022'), ('sName', 'Tomonoura'), ('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q17238551'), ('oName', 'Tomo')]
# [('s', 'http://www.wikidata.org/entity/Q8195084'), ('sName', 'mahjong tile'), ('p', 'http://www.wikidata.org/prop/direct/P1269'), ('pName', 'facet of'), ('o', 'http://www.wikidata.org/entity/Q12263'), ('oName', 'mahjong')]
# [('s', 'http://www.wikidata.org/entity/Q8197013'), ('sName', 'Amancio Muñoz de Zafra'), ('p', 'http://www.wikidata.org/prop/direct/P1038'), ('pName', 'relative'), ('o', 'http://www.wikidata.org/entity/Q105753880'), ('oName', 'Mateo Egea')]
# [('s', 'http://www.wikidata.org/entity/Q8199438'), ('sName', 'Andrés de Sola'), ('p', 'http://www.wikidata.org/prop/direct/P1066'), ('pName', 'student of'), ('o', 'http://www.wikidata.org/entity/Q11686949'), ('oName', 'José Ximénez')]
# [('s', 'http://www.wikidata.org/entity/Q8200247'), ('sName', 'Annette Aiello'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('pName', 'occupation'), ('o', 'http://www.wikidata.org/entity/Q12368980'), ('oName', 'nature photographer')]
# [('s', 'http://www.wikidata.org/entity/Q8200247'), ('sName', 'Annette Aiello'), ('p', 'http://www.wikidata.org/prop/direct/P108'), ('pName', 'employer'), ('o', 'http://www.wikidata.org/entity/Q1673980'), ('oName', 'Smithsonian Tropical Research Institute')]
# [('s', 'http://www.wikidata.org/entity/Q8200777'), ('sName', 'Anthony Walker'), ('p', 'http://www.wikidata.org/prop/direct/P1343'), ('pName', 'described by source'), ('o', 'http://www.wikidata.org/entity/Q17037575'), ('oName', 'Oxford Biography Index')]
# [('s', 'http://www.wikidata.org/entity/Q8202323'), ('sName', 'Alcainça-Moinhos halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q8202353'), ('sName', 'Bicanho Halt'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q8213303'), ('sName', 'Bunguran Utara'), ('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q10100'), ('oName', 'Natuna')]
# [('s', 'http://www.wikidata.org/entity/Q8779275'), ('sName', 'Amieira train station'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q8841005'), ('sName', 'Malveira train station'), ('p', 'http://www.wikidata.org/prop/direct/P795'), ('pName', 'located on linear feature'), ('o', 'http://www.wikidata.org/entity/Q1160445'), ('oName', 'Linha do Oeste')]
# [('s', 'http://www.wikidata.org/entity/Q95452024'), ('sName', 'Template:Vice Presidents of the Maldives'), ('p', 'http://www.wikidata.org/prop/direct/P1423'), ('pName', 'template has topic'), ('o', 'http://www.wikidata.org/entity/Q10999435'), ('oName', 'Vice President of the Maldives')]
# [('s', 'http://www.wikidata.org/entity/Q81904264'), ('sName', 'Kim Ji-min'), ('p', 'http://www.wikidata.org/prop/direct/P1344'), ('pName', 'participant in'), ('o', 'http://www.wikidata.org/entity/Q1053559'), ('oName', '2020 Winter Youth Olympics')]
# [('s', 'http://www.wikidata.org/entity/Q17211428'), ('sName', 'Shigahondōri, Nagoya'), ('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q1207964'), ('oName', 'Kita-ku')]
# [('s', 'http://www.wikidata.org/entity/Q17218089'), ('sName', 'Shimmei-chō, Nagoya'), ('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q1207964'), ('oName', 'Kita-ku')]
# [('s', 'http://www.wikidata.org/entity/Q17222169'), ('sName', 'Yanagihara, Nagoya'), ('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q1207964'), ('oName', 'Kita-ku')]
# [('s', 'http://www.wikidata.org/entity/Q17228019'), ('sName', 'Onari-tōri, Nagoya'), ('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q1207964'), ('oName', 'Kita-ku')]
# [('s', 'http://www.wikidata.org/entity/Q17482735'), ('sName', 'Turó de Montcortal'), ('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q13010'), ('oName', 'Arbúcies')]
# [('s', 'http://www.wikidata.org/entity/Q17482780'), ('sName', 'Turó de Montsoriu'), ('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q13010'), ('oName', 'Arbúcies')]
# [('s', 'http://www.wikidata.org/entity/Q17588022'), ('sName', 'Bassa de la Farga'), ('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q13010'), ('oName', 'Arbúcies')]
# [('s', 'http://www.wikidata.org/entity/Q17614805'), ('sName', 'muntanya de Can Fonoll'), ('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q13010'), ('oName', 'Arbúcies')]
# [('s', 'http://www.wikidata.org/entity/Q5289551'), ('sName', 'Dolores Piperno'), ('p', 'http://www.wikidata.org/prop/direct/P108'), ('pName', 'employer'), ('o', 'http://www.wikidata.org/entity/Q1673980'), ('oName', 'Smithsonian Tropical Research Institute')]
# [('s', 'http://www.wikidata.org/entity/Q91336419'), ('sName', 'Tommy Merlyn'), ('p', 'http://www.wikidata.org/prop/direct/P119'), ('pName', 'place of burial'), ('o', 'http://www.wikidata.org/entity/Q1419655'), ('oName', 'Star City')]
# [('s', 'http://www.wikidata.org/entity/Q91376977'), ('sName', 'Monica Munoz-Torres'), ('p', 'http://www.wikidata.org/prop/direct/P108'), ('pName', 'employer'), ('o', 'http://www.wikidata.org/entity/Q1673980'), ('oName', 'Smithsonian Tropical Research Institute')]
# [('s', 'http://www.wikidata.org/entity/Q30902089'), ('sName', 'Luis Manuel Fernández'), ('p', 'http://www.wikidata.org/prop/direct/P108'), ('pName', 'employer'), ('o', 'http://www.wikidata.org/entity/Q1475831'), ('oName', 'Venezolana de Televisión')]
# [('s', 'http://www.wikidata.org/entity/Q60684635'), ('sName', 'S. Joseph Wright'), ('p', 'http://www.wikidata.org/prop/direct/P108'), ('pName', 'employer'), ('o', 'http://www.wikidata.org/entity/Q1673980'), ('oName', 'Smithsonian Tropical Research Institute')]
# [('s', 'http://www.wikidata.org/entity/Q38780585'), ('sName', 'First Minister of British Honduras'), ('p', 'http://www.wikidata.org/prop/direct/P1001'), ('pName', 'applies to jurisdiction'), ('o', 'http://www.wikidata.org/entity/Q1643555'), ('oName', 'British Honduras')]
# [('s', 'http://www.wikidata.org/entity/Q11325962'), ('sName', 'Hyatt Regency Kyoto'), ('p', 'http://www.wikidata.org/prop/direct/P127'), ('pName', 'owned by'), ('o', 'http://www.wikidata.org/entity/Q11292651'), ('oName', 'Orix Real Estate')]
# [('s', 'http://www.wikidata.org/entity/Q18527476'), ('sName', 'David Brown'), ('p', 'http://www.wikidata.org/prop/direct/P1343'), ('pName', 'described by source'), ('o', 'http://www.wikidata.org/entity/Q17037575'), ('oName', 'Oxford Biography Index')]
# [('s', 'http://www.wikidata.org/entity/Q10863554'), ('sName', 'Ryūgasaki Domain'), ('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q1055353'), ('oName', 'Hitachi Province')]
# [('s', 'http://www.wikidata.org/entity/Q18005572'), ('sName', "Serra d'en Pere Bord"), ('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q13010'), ('oName', 'Arbúcies')]
# [('s', 'http://www.wikidata.org/entity/Q18529777'), ('sName', 'James Brown'), ('p', 'http://www.wikidata.org/prop/direct/P1343'), ('pName', 'described by source'), ('o', 'http://www.wikidata.org/entity/Q17037575'), ('oName', 'Oxford Biography Index')]
# [('s', 'http://www.wikidata.org/entity/Q18530178'), ('sName', 'John Brown'), ('p', 'http://www.wikidata.org/prop/direct/P1343'), ('pName', 'described by source'), ('o', 'http://www.wikidata.org/entity/Q17037575'), ('oName', 'Oxford Biography Index')]
# [('s', 'http://www.wikidata.org/entity/Q18810862'), ('sName', 'John Robinson'), ('p', 'http://www.wikidata.org/prop/direct/P1343'), ('pName', 'described by source'), ('o', 'http://www.wikidata.org/entity/Q17037575'), ('oName', 'Oxford Biography Index')]
# [('s', 'http://www.wikidata.org/entity/Q18810881'), ('sName', 'John Merry Ross'), ('p', 'http://www.wikidata.org/prop/direct/P1343'), ('pName', 'described by source'), ('o', 'http://www.wikidata.org/entity/Q17037575'), ('oName', 'Oxford Biography Index')]
# [('s', 'http://www.wikidata.org/entity/Q21338376'), ('sName', 'George R. Angehr'), ('p', 'http://www.wikidata.org/prop/direct/P108'), ('pName', 'employer'), ('o', 'http://www.wikidata.org/entity/Q1673980'), ('oName', 'Smithsonian Tropical Research Institute')]
# [('s', 'http://www.wikidata.org/entity/Q108386354'), ('sName', 'William P. Leonard'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('pName', 'occupation'), ('o', 'http://www.wikidata.org/entity/Q12368980'), ('oName', 'nature photographer')]
# [('s', 'http://www.wikidata.org/entity/Q64910919'), ('sName', 'Subish Palaian'), ('p', 'http://www.wikidata.org/prop/direct/P108'), ('pName', 'employer'), ('o', 'http://www.wikidata.org/entity/Q12204508'), ('oName', 'Ajman University')]
# [('s', 'http://www.wikidata.org/entity/Q57161562'), ('sName', 'Michiel van Breugel'), ('p', 'http://www.wikidata.org/prop/direct/P108'), ('pName', 'employer'), ('o', 'http://www.wikidata.org/entity/Q1673980'), ('oName', 'Smithsonian Tropical Research Institute')]
# [('s', 'http://www.wikidata.org/entity/Q76449094'), ('sName', 'Victoria Stirnemann'), ('p', 'http://www.wikidata.org/prop/direct/P1344'), ('pName', 'participant in'), ('o', 'http://www.wikidata.org/entity/Q1053559'), ('oName', '2020 Winter Youth Olympics')]
# [('s', 'http://www.wikidata.org/entity/Q81904099'), ('sName', 'Benjamin Kapp'), ('p', 'http://www.wikidata.org/prop/direct/P1344'), ('pName', 'participant in'), ('o', 'http://www.wikidata.org/entity/Q1053559'), ('oName', '2020 Winter Youth Olympics')]
# [('s', 'http://www.wikidata.org/entity/Q1749545'), ('sName', 'Nova Zagora Municipality'), ('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q113120'), ('oName', 'Sliven Province')]
# [('s', 'http://www.wikidata.org/entity/Q3031457'), ('sName', 'Mananjary'), ('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q1462671'), ('oName', 'Vatovavy-Fitovinany')]
# [('s', 'http://www.wikidata.org/entity/Q7850092'), ('sName', 'Tsukuba district'), ('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q1055353'), ('oName', 'Hitachi Province')]
# [('s', 'http://www.wikidata.org/entity/Q24232048'), ('sName', 'Pulau Tiga Barat'), ('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q10100'), ('oName', 'Natuna')]
# [('s', 'http://www.wikidata.org/entity/Q8213242'), ('sName', 'Pulau Tiga'), ('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q10100'), ('oName', 'Natuna')]
# [('s', 'http://www.wikidata.org/entity/Q18526878'), ('sName', 'John Evans'), ('p', 'http://www.wikidata.org/prop/direct/P1343'), ('pName', 'described by source'), ('o', 'http://www.wikidata.org/entity/Q17037575'), ('oName', 'Oxford Biography Index')]
# [('s', 'http://www.wikidata.org/entity/Q18527381'), ('sName', 'John Murray'), ('p', 'http://www.wikidata.org/prop/direct/P1343'), ('pName', 'described by source'), ('o', 'http://www.wikidata.org/entity/Q17037575'), ('oName', 'Oxford Biography Index')]
# [('s', 'http://www.wikidata.org/entity/Q18527772'), ('sName', 'John Walker'), ('p', 'http://www.wikidata.org/prop/direct/P1343'), ('pName', 'described by source'), ('o', 'http://www.wikidata.org/entity/Q17037575'), ('oName', 'Oxford Biography Index')]
# [('s', 'http://www.wikidata.org/entity/Q18529684'), ('sName', 'David Davies'), ('p', 'http://www.wikidata.org/prop/direct/P1343'), ('pName', 'described by source'), ('o', 'http://www.wikidata.org/entity/Q17037575'), ('oName', 'Oxford Biography Index')]
# [('s', 'http://www.wikidata.org/entity/Q18530173'), ('sName', 'John Brown'), ('p', 'http://www.wikidata.org/prop/direct/P1343'), ('pName', 'described by source'), ('o', 'http://www.wikidata.org/entity/Q17037575'), ('oName', 'Oxford Biography Index')]
# [('s', 'http://www.wikidata.org/entity/Q18530181'), ('sName', 'John Wright Brown'), ('p', 'http://www.wikidata.org/prop/direct/P1343'), ('pName', 'described by source'), ('o', 'http://www.wikidata.org/entity/Q17037575'), ('oName', 'Oxford Biography Index')]
# [('s', 'http://www.wikidata.org/entity/Q18534214'), ('sName', 'John Taylor'), ('p', 'http://www.wikidata.org/prop/direct/P1343'), ('pName', 'described by source'), ('o', 'http://www.wikidata.org/entity/Q17037575'), ('oName', 'Oxford Biography Index')]
# [('s', 'http://www.wikidata.org/entity/Q18546621'), ('sName', 'John Roland Phillips'), ('p', 'http://www.wikidata.org/prop/direct/P1343'), ('pName', 'described by source'), ('o', 'http://www.wikidata.org/entity/Q17037575'), ('oName', 'Oxford Biography Index')]
# [('s', 'http://www.wikidata.org/entity/Q18546651'), ('sName', 'John Williams'), ('p', 'http://www.wikidata.org/prop/direct/P1343'), ('pName', 'described by source'), ('o', 'http://www.wikidata.org/entity/Q17037575'), ('oName', 'Oxford Biography Index')]
# [('s', 'http://www.wikidata.org/entity/Q18546656'), ('sName', 'John Bickerton Williams'), ('p', 'http://www.wikidata.org/prop/direct/P1343'), ('pName', 'described by source'), ('o', 'http://www.wikidata.org/entity/Q17037575'), ('oName', 'Oxford Biography Index')]
# [('s', 'http://www.wikidata.org/entity/Q7528143'), ('sName', 'Sir John Williams, 1st Baronet, of the City of London'), ('p', 'http://www.wikidata.org/prop/direct/P1343'), ('pName', 'described by source'), ('o', 'http://www.wikidata.org/entity/Q17037575'), ('oName', 'Oxford Biography Index')]
# [('s', 'http://www.wikidata.org/entity/Q18593621'), ('sName', 'William Moore'), ('p', 'http://www.wikidata.org/prop/direct/P1343'), ('pName', 'described by source'), ('o', 'http://www.wikidata.org/entity/Q17037575'), ('oName', 'Oxford Biography Index')]
# [('s', 'http://www.wikidata.org/entity/Q18729868'), ('sName', 'Entesa per Arbúcies'), ('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q13010'), ('oName', 'Arbúcies')]
# [('s', 'http://www.wikidata.org/entity/Q12475627'), ('sName', 'Belimbing, Melawi'), ('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q14162'), ('oName', 'Melawi')]
# [('s', 'http://www.wikidata.org/entity/Q8213273'), ('sName', 'Serasan'), ('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q10100'), ('oName', 'Natuna')]
# [('s', 'http://www.wikidata.org/entity/Q1905256'), ('sName', 'Martin Wikelski'), ('p', 'http://www.wikidata.org/prop/direct/P108'), ('pName', 'employer'), ('o', 'http://www.wikidata.org/entity/Q1673980'), ('oName', 'Smithsonian Tropical Research Institute')]
# [('s', 'http://www.wikidata.org/entity/Q21611757'), ('sName', 'Juan Carlos Villarreal Aguilar'), ('p', 'http://www.wikidata.org/prop/direct/P108'), ('pName', 'employer'), ('o', 'http://www.wikidata.org/entity/Q1673980'), ('oName', 'Smithsonian Tropical Research Institute')]
# [('s', 'http://www.wikidata.org/entity/Q24035454'), ('sName', 'el Vidal'), ('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q13010'), ('oName', 'Arbúcies')]
# [('s', 'http://www.wikidata.org/entity/Q57080337'), ('sName', 'David I Kline'), ('p', 'http://www.wikidata.org/prop/direct/P108'), ('pName', 'employer'), ('o', 'http://www.wikidata.org/entity/Q1673980'), ('oName', 'Smithsonian Tropical Research Institute')]
# [('s', 'http://www.wikidata.org/entity/Q44790072'), ('sName', 'Sean R. Connolly'), ('p', 'http://www.wikidata.org/prop/direct/P108'), ('pName', 'employer'), ('o', 'http://www.wikidata.org/entity/Q1673980'), ('oName', 'Smithsonian Tropical Research Institute')]
# [('s', 'http://www.wikidata.org/entity/Q60297756'), ('sName', 'Orpheus M Butler'), ('p', 'http://www.wikidata.org/prop/direct/P108'), ('pName', 'employer'), ('o', 'http://www.wikidata.org/entity/Q1673980'), ('oName', 'Smithsonian Tropical Research Institute')]
# [('s', 'http://www.wikidata.org/entity/Q19294986'), ('sName', 'Louis Berlioz'), ('p', 'http://www.wikidata.org/prop/direct/P101'), ('pName', 'field of work'), ('o', 'http://www.wikidata.org/entity/Q121713'), ('oName', 'acupuncture')]
# [('s', 'http://www.wikidata.org/entity/Q7980959'), ('sName', 'welfare fraud'), ('p', 'http://www.wikidata.org/prop/direct/P1269'), ('pName', 'facet of'), ('o', 'http://www.wikidata.org/entity/Q11497309'), ('oName', 'economic support')]
# [('s', 'http://www.wikidata.org/entity/Q7371387'), ('sName', 'Nagoya Expressway 16'), ('p', 'http://www.wikidata.org/prop/direct/P126'), ('pName', 'maintained by'), ('o', 'http://www.wikidata.org/entity/Q11415304'), ('oName', 'Nagoya Expressway Public Corporation')]
# [('s', 'http://www.wikidata.org/entity/Q80545'), ('sName', 'Oshiage Station'), ('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q11497641'), ('oName', 'Oshiage')]
# [('s', 'http://www.wikidata.org/entity/Q8191440'), ('sName', 'Nagoya Highway 11'), ('p', 'http://www.wikidata.org/prop/direct/P126'), ('pName', 'maintained by'), ('o', 'http://www.wikidata.org/entity/Q11415304'), ('oName', 'Nagoya Expressway Public Corporation')]
# [('s', 'http://www.wikidata.org/entity/Q8191440'), ('sName', 'Nagoya Highway 11'), ('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q1207964'), ('oName', 'Kita-ku')]
# [('s', 'http://www.wikidata.org/entity/Q8191440'), ('sName', 'Nagoya Highway 11'), ('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q1345562'), ('oName', 'Toyoyama')]
# [('s', 'http://www.wikidata.org/entity/Q4423406'), ('sName', 'Sliven Municipality'), ('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q113120'), ('oName', 'Sliven Province')]
# [('s', 'http://www.wikidata.org/entity/Q25563103'), ('sName', 'Warangal'), ('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q15399'), ('oName', 'Warangal District')]
# [('s', 'http://www.wikidata.org/entity/Q12383937'), ('sName', 'Augas Santas, Allariz'), ('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q1438879'), ('oName', 'Allariz')]
# [('s', 'http://www.wikidata.org/entity/Q2609479'), ('sName', 'Kotel Municipality'), ('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q113120'), ('oName', 'Sliven Province')]
# [('s', 'http://www.wikidata.org/entity/Q11494799'), ('sName', 'Aichi Prefectural Road Route 62'), ('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q1345562'), ('oName', 'Toyoyama')]
# [('s', 'http://www.wikidata.org/entity/Q12358779'), ('sName', 'Aleksandr Podkopajev'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('pName', 'occupation'), ('o', 'http://www.wikidata.org/entity/Q106823762'), ('oName', 'veterinary scientist')]
# [('s', 'http://www.wikidata.org/entity/Q12371070'), ('sName', 'Nikolai Prozorov'), ('p', 'http://www.wikidata.org/prop/direct/P106'), ('pName', 'occupation'), ('o', 'http://www.wikidata.org/entity/Q106823762'), ('oName', 'veterinary scientist')]
# [('s', 'http://www.wikidata.org/entity/Q12482400'), ('sName', 'Ella Hilir'), ('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q14162'), ('oName', 'Melawi')]
# [('s', 'http://www.wikidata.org/entity/Q8213279'), ('sName', 'Midai'), ('p', 'http://www.wikidata.org/prop/direct/P131'), ('pName', 'located in the administrative territorial entity'), ('o', 'http://www.wikidata.org/entity/Q10100'), ('oName', 'Natuna')]
# 100

# %%
# Consider the tennis players born after 1975, return who won more Grand Slams and cut the result to the top-10 (the result set must be a list of triples player IRI, label and #victories).
# Q1426 = Roger Federer
# wdt:P1344 (participant in)
# wdt:P2522 (victory)
#[('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('o', 'http://www.wikidata.org/entity/P569'), ('oName', 'date of birth')]
# 1) getting winners dob 

queryString = """

SELECT DISTINCT ?s ?sName "birthday" ?o ?oName
WHERE {
   # ?s wdt:P3150 ?o.
   # ?s sc:name ?sName.
   # ?o sc:name ?oName.
   
   FILTER (REGEX(?oName,"August 8","i"))
}
LIMIT 100
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('s', 'http://www.wikidata.org/entity/Q42012085'), ('sName', 'Hachiman Hikigaya'), ('callret-2', 'birthday'), ('o', 'http://www.wikidata.org/entity/Q2780'), ('oName', 'August 8')]
# [('s', 'http://www.wikidata.org/entity/Q11541253'), ('sName', 'Natsuko Kusuda'), ('callret-2', 'birthday'), ('o', 'http://www.wikidata.org/entity/Q2780'), ('oName', 'August 8')]
# [('s', 'http://www.wikidata.org/entity/Q107038831'), ('sName', 'Hoho Kajino'), ('callret-2', 'birthday'), ('o', 'http://www.wikidata.org/entity/Q2780'), ('oName', 'August 8')]
# [('s', 'http://www.wikidata.org/entity/Q11256924'), ('sName', 'Ryuryū Akari'), ('callret-2', 'birthday'), ('o', 'http://www.wikidata.org/entity/Q2780'), ('oName', 'August 8')]
# [('s', 'http://www.wikidata.org/entity/Q11536787'), ('sName', 'Ryū Katsuragi'), ('callret-2', 'birthday'), ('o', 'http://www.wikidata.org/entity/Q2780'), ('oName', 'August 8')]
# [('s', 'http://www.wikidata.org/entity/Q106478679'), ('sName', 'Tatsuya Nakamura'), ('callret-2', 'birthday'), ('o', 'http://www.wikidata.org/entity/Q2780'), ('oName', 'August 8')]
# [('s', 'http://www.wikidata.org/entity/Q107026111'), ('sName', 'Setsuna Yuki'), ('callret-2', 'birthday'), ('o', 'http://www.wikidata.org/entity/Q2780'), ('oName', 'August 8')]
# [('s', 'http://www.wikidata.org/entity/Q22128446'), ('sName', 'Hachi Hoshikawa'), ('callret-2', 'birthday'), ('o', 'http://www.wikidata.org/entity/Q2780'), ('oName', 'August 8')]
# [('s', 'http://www.wikidata.org/entity/Q16730112'), ('sName', 'Milauna Jackson'), ('callret-2', 'birthday'), ('o', 'http://www.wikidata.org/entity/Q2780'), ('oName', 'August 8')]
# [('s', 'http://www.wikidata.org/entity/Q11483663'), ('sName', 'Rei Hirano'), ('callret-2', 'birthday'), ('o', 'http://www.wikidata.org/entity/Q2780'), ('oName', 'August 8')]
# [('s', 'http://www.wikidata.org/entity/Q54292702'), ('sName', 'Ruri Umino'), ('callret-2', 'birthday'), ('o', 'http://www.wikidata.org/entity/Q2780'), ('oName', 'August 8')]
# [('s', 'http://www.wikidata.org/entity/Q90681265'), ('sName', 'Leif'), ('callret-2', 'birthday'), ('o', 'http://www.wikidata.org/entity/Q2780'), ('oName', 'August 8')]
# [('s', 'http://www.wikidata.org/entity/Q107677643'), ('sName', 'Sarah Berman'), ('callret-2', 'birthday'), ('o', 'http://www.wikidata.org/entity/Q2780'), ('oName', 'August 8')]
# 13

# %%
# Consider the tennis players born after 1975, return who won more Grand Slams and cut the result to the top-10 (the result set must be a list of triples player IRI, label and #victories).
# Q1426 = Roger Federer -> August 8, 1981
# wdt:P1344 (participant in)
# wdt:P2522 (victory)
#[('p', 'http://www.wikidata.org/prop/direct/P1963'), ('pName', 'properties for this type'), ('o', 'http://www.wikidata.org/entity/P569'), ('oName', 'date of birth')]
# 1) getting winners dob 

queryString = """

SELECT DISTINCT ?s ?sName ?p ?pName ?o ?oName
WHERE {
   # ?s ?p ?o.
   # ?s sc:name ?sName.
   # ?p sc:name ?pName.
   # ?o sc:name ?oName.
   
   # today filter with regex not working
   FILTER (REGEX(?pName,"birth","i"))
   
   
   #takes to long
   #FILTER (?p not in (wdt:P19, wdt:P3150))
}
LIMIT 5
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('s', 'http://www.wikidata.org/entity/Q95452024'), ('sName', 'Template:Vice Presidents of the Maldives'), ('p', 'http://www.wikidata.org/prop/direct/P1423'), ('pName', 'template has topic'), ('o', 'http://www.wikidata.org/entity/Q10999435'), ('oName', 'Vice President of the Maldives')]
# [('s', 'http://www.wikidata.org/entity/Q25752552'), ('sName', 'Template:2001 in Europe'), ('p', 'http://www.wikidata.org/prop/direct/P1423'), ('pName', 'template has topic'), ('o', 'http://www.wikidata.org/entity/Q17111750'), ('oName', '2001 in Europe')]
# [('s', 'http://www.wikidata.org/entity/Q6675314'), ('sName', 'Template:Alcest'), ('p', 'http://www.wikidata.org/prop/direct/P1423'), ('pName', 'template has topic'), ('o', 'http://www.wikidata.org/entity/Q1517060'), ('oName', 'Alcest')]
# [('s', 'http://www.wikidata.org/entity/Q22785857'), ('sName', 'Template:2006 in Europe'), ('p', 'http://www.wikidata.org/prop/direct/P1423'), ('pName', 'template has topic'), ('o', 'http://www.wikidata.org/entity/Q17111782'), ('oName', '2006 in Europe')]
# [('s', 'http://www.wikidata.org/entity/Q85816744'), ('sName', 'Yodli'), ('p', 'http://www.wikidata.org/prop/direct/P1268'), ('pName', 'represents'), ('o', 'http://www.wikidata.org/entity/Q1053559'), ('oName', '2020 Winter Youth Olympics')]
# 5

# %% [markdown]
# # General instructions
#
# The goal of the project is to materialize a set of **exploratory workloads** over a real-world, large-scale,  open-domain KG: [WikiData](https://www.wikidata.org/wiki/Wikidata:Main_Page)
#
# An exploratory workload  is composed by a set of queries, where each query is related to the information obtained previously.
#
# An exploratory workload starts with a usually vague, open ended question, and does not assume the person issuing the workload has a clear understanding of the data contained in the target database or its structure.
#
# Remeber that:
#
# 1. All the queries must run in the python notebook
# 2. You can use classes and properties only if you find them via a SPARQL query that must be present in the notebook
# 3. You do not delete useless queries. Keep everything that is synthatically valid
#
# ```
# ?p <http://schema.org/name> ?name .
# ```
#
#     is the BGP returning a human-readable name of a property or a class in Wikidata.

# %%
## SETUP used later

from SPARQLWrapper import SPARQLWrapper, JSON


prefixString = """
##-movie2-##
PREFIX wd: <http://www.wikidata.org/entity/> 
PREFIX wdt: <http://www.wikidata.org/prop/direct/> 
PREFIX sc: <http://schema.org/>
"""

# select and construct queries
def run_query(queryString,verbose = True):
    to_run = prefixString + "\n" + queryString

    sparql = SPARQLWrapper("http://a256-gc1-02.srv.aau.dk:5820/sparql")
    sparql.setTimeout(300)
    sparql.setReturnFormat(JSON)
    sparql.setQuery(to_run)

    try :
        results = sparql.query()
        json_results = results.convert()
        if len(json_results['results']['bindings'])==0:
            print("Empty")
            return []
        array = []
        for bindings in json_results['results']['bindings']:
            app =  [ (var, value['value'])  for var, value in bindings.items() ] 
            if verbose:
                print( app)
            array.append(app)
        if verbose:
            print(len(array))
        return array

    except Exception as e :
        print("The operation failed", e)
    
# ASk queries
def run_ask_query(queryString):
    to_run = prefixString + "\n" + queryString

    sparql = SPARQLWrapper("http://a256-gc1-02.srv.aau.dk:5820/sparql")
    sparql.setTimeout(300)
    sparql.setReturnFormat(JSON)
    sparql.setQuery(to_run)

    try :
        return sparql.query().convert()

    except Exception as e :
        print("The operation failed", e)

# %% [markdown]
# # Movie Workflow Series ("Disney explorative search")
#
# Consider the following exploratory information need:
#
# > investigate films produced by Disney and compare workers among films.

# %% [markdown]
# ## Useful URIs for the current workflow
# The following are given:
#
# | IRI           | Description   | Role      |
# | -----------   | -----------   |-----------|
# | `wdt:P1647`   | subproperty   | predicate |
# | `wdt:P31`     | instance of   | predicate |
# | `wdt:P106`    | profession    | predicate |
# | `wdt:P279`    | subclass      | predicate |
# | `wdt:P27`     | nationality   | predicate |
# | `wdt:P106`     | profession   | predicate |
# | `wdt:P3342`     | Significant person       | predicate |
# | `wd:Q5`| Human       | node |
# | `wd:Q36479`    | The Lion King      | node |

# %% [markdown]
# Also consider
#
# ```
# wd:Q36479 ?p ?obj .
# ```
#
# is the BGP to retrieve all **properties of The Lion King**
#
# Please consider that when you return a resource, you should return the IRI and the label of the resource. In particular, when the task require you to identify a BGP the result set must always be a list of couples IRI - label.
#
# The workload should:
#
#
# 1. Identify the BGP for films
#
# 2. Identify the BGP for Walt Disney Animation Studios
#
# 3. Identify the BGP for Walt Disney (person)
#
# 4. List all the films created by the Walt Disney Animation Studios while Walt Disney was alive (the result set must be a list of couples films IRI and label).
#
# 5. Find the name of the voice actors who participated in more than 5 films by the Walt Disney Animation Studios (the result set must be a list of triples voice actors IRI, label and #films).
#
# 6. Identify the BGP for the film "The Little Mermaid"
#
# 7. Find who worked on both "The Little Mermaid" and "The Lion King" (the result set must be a list of couples worker IRI and label).
#
# 8. Identify the BGP for Academy Awards
#
# 9. For each films created by the Walt Disney Animation Studios return the number of nomination for an Academy Awards. Return only films with at least one nomination. (the result set must be triples of films IRI, label and #nomination).

# %% [markdown]
# ## Task 1

# %%
queryString = """
SELECT DISTINCT ?p ?name
WHERE { 
    wd:Q36479 ?p ?obj .
    FILTER(!isLiteral(?obj)).
    # ?p sc:name ?name.
} 
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P3092'), ('name', 'film crew member')]
# [('p', 'http://www.wikidata.org/prop/direct/P1040'), ('name', 'film editor')]
# [('p', 'http://www.wikidata.org/prop/direct/P136'), ('name', 'genre')]
# [('p', 'http://www.wikidata.org/prop/direct/P1411'), ('name', 'nominated for')]
# [('p', 'http://www.wikidata.org/prop/direct/P1434'), ('name', 'takes place in fictional universe')]
# [('p', 'http://www.wikidata.org/prop/direct/P144'), ('name', 'based on')]
# [('p', 'http://www.wikidata.org/prop/direct/P154'), ('name', 'logo image')]
# [('p', 'http://www.wikidata.org/prop/direct/P1552'), ('name', 'has quality')]
# [('p', 'http://www.wikidata.org/prop/direct/P156'), ('name', 'followed by')]
# [('p', 'http://www.wikidata.org/prop/direct/P162'), ('name', 'producer')]
# [('p', 'http://www.wikidata.org/prop/direct/P1657'), ('name', 'MPAA film rating')]
# [('p', 'http://www.wikidata.org/prop/direct/P166'), ('name', 'award received')]
# [('p', 'http://www.wikidata.org/prop/direct/P175'), ('name', 'performer')]
# [('p', 'http://www.wikidata.org/prop/direct/P179'), ('name', 'part of the series')]
# [('p', 'http://www.wikidata.org/prop/direct/P1889'), ('name', 'different from')]
# [('p', 'http://www.wikidata.org/prop/direct/P2079'), ('name', 'fabrication method')]
# [('p', 'http://www.wikidata.org/prop/direct/P272'), ('name', 'production company')]
# [('p', 'http://www.wikidata.org/prop/direct/P2747'), ('name', 'Filmiroda rating')]
# [('p', 'http://www.wikidata.org/prop/direct/P2758'), ('name', 'CNC film rating (France)')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('name', 'instance of')]
# [('p', 'http://www.wikidata.org/prop/direct/P3402'), ('name', 'CNC film rating (Romania)')]
# [('p', 'http://www.wikidata.org/prop/direct/P364'), ('name', 'original language of film or TV show')]
# [('p', 'http://www.wikidata.org/prop/direct/P3834'), ('name', 'RTC film rating')]
# [('p', 'http://www.wikidata.org/prop/direct/P437'), ('name', 'distribution format')]
# [('p', 'http://www.wikidata.org/prop/direct/P462'), ('name', 'color')]
# [('p', 'http://www.wikidata.org/prop/direct/P495'), ('name', 'country of origin')]
# [('p', 'http://www.wikidata.org/prop/direct/P4969'), ('name', 'derivative work')]
# [('p', 'http://www.wikidata.org/prop/direct/P5021'), ('name', 'assessment')]
# [('p', 'http://www.wikidata.org/prop/direct/P57'), ('name', 'director')]
# [('p', 'http://www.wikidata.org/prop/direct/P58'), ('name', 'screenwriter')]
# [('p', 'http://www.wikidata.org/prop/direct/P674'), ('name', 'characters')]
# [('p', 'http://www.wikidata.org/prop/direct/P747'), ('name', 'has edition or translation')]
# [('p', 'http://www.wikidata.org/prop/direct/P750'), ('name', 'distributed by')]
# [('p', 'http://www.wikidata.org/prop/direct/P793'), ('name', 'significant event')]
# [('p', 'http://www.wikidata.org/prop/direct/P8345'), ('name', 'media franchise')]
# [('p', 'http://www.wikidata.org/prop/direct/P840'), ('name', 'narrative location')]
# [('p', 'http://www.wikidata.org/prop/direct/P8411'), ('name', 'set in environment')]
# [('p', 'http://www.wikidata.org/prop/direct/P856'), ('name', 'official website')]
# [('p', 'http://www.wikidata.org/prop/direct/P86'), ('name', 'composer')]
# [('p', 'http://www.wikidata.org/prop/direct/P910'), ('name', "topic's main category")]
# [('p', 'http://www.wikidata.org/prop/direct/P941'), ('name', 'inspired by')]
# [('p', 'http://www.wikidata.org/prop/direct/P2554'), ('name', 'production designer')]
# [('p', 'http://www.wikidata.org/prop/direct/P1431'), ('name', 'executive producer')]
# [('p', 'http://www.wikidata.org/prop/direct/P406'), ('name', 'soundtrack release')]
# [('p', 'http://www.wikidata.org/prop/direct/P942'), ('name', 'theme music')]
# [('p', 'http://www.wikidata.org/prop/direct/P3174'), ('name', 'art director')]
# [('p', 'http://www.wikidata.org/prop/direct/P725'), ('name', 'voice actor')]
# [('p', 'http://www.wikidata.org/prop/direct/P3275'), ('name', 'storyboard artist')]
# [('p', 'http://www.wikidata.org/prop/direct/P6942'), ('name', 'animator')]
# 49

# %%
queryString = """
SELECT DISTINCT ?obj ?name
WHERE { 
    wd:Q36479 wdt:P31 ?obj .
    # ?obj sc:name ?name.
} 
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('obj', 'http://www.wikidata.org/entity/Q29168811'), ('name', 'animated feature film')]
# 1

# %%
queryString = """
SELECT DISTINCT ?obj ?name
WHERE { 
    wd:Q36479 wdt:P31/wdt:P279+ ?obj .
    # ?obj sc:name ?name.
} 
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('obj', 'http://www.wikidata.org/entity/Q15621286'), ('name', 'intellectual work')]
# [('obj', 'http://www.wikidata.org/entity/Q20937557'), ('name', 'series')]
# [('obj', 'http://www.wikidata.org/entity/Q2150504'), ('name', 'signal')]
# [('obj', 'http://www.wikidata.org/entity/Q35120'), ('name', 'entity')]
# [('obj', 'http://www.wikidata.org/entity/Q2995644'), ('name', 'result')]
# [('obj', 'http://www.wikidata.org/entity/Q1150771'), ('name', 'output')]
# [('obj', 'http://www.wikidata.org/entity/Q11028'), ('name', 'information')]
# [('obj', 'http://www.wikidata.org/entity/Q11424'), ('name', 'film')]
# [('obj', 'http://www.wikidata.org/entity/Q17537576'), ('name', 'creative work')]
# [('obj', 'http://www.wikidata.org/entity/Q386724'), ('name', 'work')]
# [('obj', 'http://www.wikidata.org/entity/Q42848'), ('name', 'data')]
# [('obj', 'http://www.wikidata.org/entity/Q202866'), ('name', 'animated film')]
# [('obj', 'http://www.wikidata.org/entity/Q174984'), ('name', 'signal')]
# [('obj', 'http://www.wikidata.org/entity/Q24869'), ('name', 'feature film')]
# [('obj', 'http://www.wikidata.org/entity/Q18593264'), ('name', 'item of collection or exhibition')]
# [('obj', 'http://www.wikidata.org/entity/Q28813620'), ('name', 'set')]
# [('obj', 'http://www.wikidata.org/entity/Q15401930'), ('name', 'product')]
# [('obj', 'http://www.wikidata.org/entity/Q16887380'), ('name', 'group')]
# [('obj', 'http://www.wikidata.org/entity/Q28877'), ('name', 'goods')]
# [('obj', 'http://www.wikidata.org/entity/Q3695082'), ('name', 'sign')]
# [('obj', 'http://www.wikidata.org/entity/Q4502142'), ('name', 'visual artwork')]
# [('obj', 'http://www.wikidata.org/entity/Q7184903'), ('name', 'abstract object')]
# [('obj', 'http://www.wikidata.org/entity/Q838948'), ('name', 'work of art')]
# [('obj', 'http://www.wikidata.org/entity/Q2431196'), ('name', 'audiovisual work')]
# [('obj', 'http://www.wikidata.org/entity/Q478798'), ('name', 'image')]
# [('obj', 'http://www.wikidata.org/entity/Q11795009'), ('name', 'image')]
# [('obj', 'http://www.wikidata.org/entity/Q488383'), ('name', 'object')]
# [('obj', 'http://www.wikidata.org/entity/Q194980'), ('name', 'intangible good')]
# [('obj', 'http://www.wikidata.org/entity/Q2897903'), ('name', 'goods and services')]
# [('obj', 'http://www.wikidata.org/entity/Q58415929'), ('name', 'spatio-temporal entity')]
# [('obj', 'http://www.wikidata.org/entity/Q16686448'), ('name', 'artificial entity')]
# [('obj', 'http://www.wikidata.org/entity/Q106213450'), ('name', 'time-based work')]
# [('obj', 'http://www.wikidata.org/entity/Q733541'), ('name', 'consequence')]
# [('obj', 'http://www.wikidata.org/entity/Q10301427'), ('name', 'moving image')]
# [('obj', 'http://www.wikidata.org/entity/Q99527517'), ('name', 'collective entity')]
# 35

# %% [markdown]
# `wd:Q11424` is the class of film

# %% [markdown]
# ## Task 2

# %%
queryString = """
SELECT DISTINCT ?p ?name ?obj ?nO
WHERE { 
    wd:Q36479 ?p ?obj .
    FILTER(!isLiteral(?obj)).
    # ?obj sc:name ?nO.
    FILTER(REGEX(?nO,"[D,d]isney")).
    # ?p sc:name ?name.
} 
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P179'), ('name', 'part of the series'), ('obj', 'http://www.wikidata.org/entity/Q56070713'), ('nO', 'Walt Disney Animation Studios film')]
# [('p', 'http://www.wikidata.org/prop/direct/P272'), ('name', 'production company'), ('obj', 'http://www.wikidata.org/entity/Q1047410'), ('nO', 'Walt Disney Animation Studios')]
# [('p', 'http://www.wikidata.org/prop/direct/P272'), ('name', 'production company'), ('obj', 'http://www.wikidata.org/entity/Q191224'), ('nO', 'Walt Disney Pictures')]
# [('p', 'http://www.wikidata.org/prop/direct/P750'), ('name', 'distributed by'), ('obj', 'http://www.wikidata.org/entity/Q1323594'), ('nO', 'Walt Disney Studios Motion Pictures')]
# [('p', 'http://www.wikidata.org/prop/direct/P750'), ('name', 'distributed by'), ('obj', 'http://www.wikidata.org/entity/Q54958752'), ('nO', 'Disney+')]
# 5

# %% [markdown]
# `wd:Q1047410` is the Walt Disney Animation Studios

# %% [markdown]
# ## Task 3

# %%
queryString = """
SELECT DISTINCT ?p ?name ?obj ?nO
WHERE { 
    wd:Q1047410 ?p ?obj .
    FILTER(!isLiteral(?obj)).
    # ?obj sc:name ?nO.
    FILTER(REGEX(?nO,"[D,d]isney")).
    # ?p sc:name ?name.
} 
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P112'), ('name', 'founded by'), ('obj', 'http://www.wikidata.org/entity/Q347432'), ('nO', 'Roy O. Disney')]
# [('p', 'http://www.wikidata.org/prop/direct/P112'), ('name', 'founded by'), ('obj', 'http://www.wikidata.org/entity/Q8704'), ('nO', 'Walt Disney')]
# [('p', 'http://www.wikidata.org/prop/direct/P127'), ('name', 'owned by'), ('obj', 'http://www.wikidata.org/entity/Q7414'), ('nO', 'The Walt Disney Company')]
# [('p', 'http://www.wikidata.org/prop/direct/P127'), ('name', 'owned by'), ('obj', 'http://www.wikidata.org/entity/Q191224'), ('nO', 'Walt Disney Pictures')]
# [('p', 'http://www.wikidata.org/prop/direct/P749'), ('name', 'parent organization'), ('obj', 'http://www.wikidata.org/entity/Q2216535'), ('nO', 'Walt Disney Studios')]
# [('p', 'http://www.wikidata.org/prop/direct/P910'), ('name', "topic's main category"), ('obj', 'http://www.wikidata.org/entity/Q25088476'), ('nO', 'Category:Walt Disney Animation Studios')]
# 6

# %% [markdown]
# `wd:Q8704` is Walt Disney

# %% [markdown]
# ## Task 4

# %%
queryString = """
SELECT DISTINCT ?p ?name
WHERE { 
    wd:Q36479 ?p ?obj .
    # ?p sc:name ?name.
    FILTER(REGEX(?name,"[D,d]ate")).
} 
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P577'), ('name', 'publication date')]
# 1

# %%
queryString = """
SELECT DISTINCT ?prop ?name
WHERE { 
    wd:Q8704 ?prop ?obj .
    # ?prop sc:name ?name.
    FILTER(REGEX(?name,"[D,d]ate")).
} 
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('prop', 'http://www.wikidata.org/prop/direct/P569'), ('name', 'date of birth')]
# [('prop', 'http://www.wikidata.org/prop/direct/P570'), ('name', 'date of death')]
# 2

# %%
queryString = """
SELECT DISTINCT ?film ?name
WHERE { 
    wd:Q8704 wdt:P570 ?death.
    # ?film wdt:P272 wd:Q1047410 ;
          wdt:P577 ?publ.
    FILTER(?publ < ?death).
    # ?film sc:name ?name.
} 
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('film', 'http://www.wikidata.org/entity/Q2275783'), ('name', 'The Barn Dance')]
# [('film', 'http://www.wikidata.org/entity/Q3521221'), ('name', 'The Haunted House')]
# [('film', 'http://www.wikidata.org/entity/Q3392773'), ('name', 'Playful Pluto')]
# [('film', 'http://www.wikidata.org/entity/Q2700743'), ('name', 'Clock Cleaners')]
# [('film', 'http://www.wikidata.org/entity/Q842306'), ('name', 'Saludos Amigos')]
# [('film', 'http://www.wikidata.org/entity/Q3207087'), ('name', 'Hockey Homicide')]
# [('film', 'http://www.wikidata.org/entity/Q3178943'), ('name', "Donald's Dilemma")]
# [('film', 'http://www.wikidata.org/entity/Q2399982'), ('name', 'Tea for Two Hundred')]
# [('film', 'http://www.wikidata.org/entity/Q3520106'), ('name', 'The Brave Engineer')]
# [('film', 'http://www.wikidata.org/entity/Q3228508'), ('name', 'Hold That Pose')]
# [('film', 'http://www.wikidata.org/entity/Q3028329'), ('name', 'Two Weeks Vacation')]
# [('film', 'http://www.wikidata.org/entity/Q2090328'), ('name', 'Trick or Treat')]
# [('film', 'http://www.wikidata.org/entity/Q3236849'), ('name', "Let's Stick Together")]
# [('film', 'http://www.wikidata.org/entity/Q640679'), ('name', 'Rugged Bear')]
# [('film', 'http://www.wikidata.org/entity/Q3036174'), ('name', 'Grin and Bear It')]
# [('film', 'http://www.wikidata.org/entity/Q3006129'), ('name', 'Bearly Asleep')]
# [('film', 'http://www.wikidata.org/entity/Q3036139'), ('name', 'Beezy Bear')]
# [('film', 'http://www.wikidata.org/entity/Q215617'), ('name', 'Sleeping Beauty')]
# 18

# %% [markdown]
# ## Task 5

# %%
queryString = """
SELECT ?va ?name COUNT(DISTINCT ?film) AS ?counts
WHERE { 
    # ?film wdt:P272 wd:Q1047410 .
    # ?film wdt:P725 ?va.
    # ?va sc:name ?name.
} 
GROUP BY ?va ?name
HAVING (COUNT(DISTINCT ?film) > 5)
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('va', 'http://www.wikidata.org/entity/Q264418'), ('name', 'Russi Taylor'), ('counts', '6')]
# [('va', 'http://www.wikidata.org/entity/Q310292'), ('name', 'Jim Cummings'), ('counts', '10')]
# [('va', 'http://www.wikidata.org/entity/Q178882'), ('name', 'Kristen Bell'), ('counts', '6')]
# [('va', 'http://www.wikidata.org/entity/Q349350'), ('name', 'Alan Tudyk'), ('counts', '7')]
# [('va', 'http://www.wikidata.org/entity/Q296577'), ('name', 'Frank Welker'), ('counts', '7')]
# 5

# %% [markdown]
# ## Task 6

# %%
queryString = """
SELECT DISTINCT ?film ?name
WHERE { 
    # ?film wdt:P272 wd:Q1047410 .
    # ?film sc:name ?name.
    FILTER(REGEX(?name,"[L,l]ittle")).
} 
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('film', 'http://www.wikidata.org/entity/Q944287'), ('name', 'The Little Mermaid')]
# [('film', 'http://www.wikidata.org/entity/Q270940'), ('name', 'Chicken Little')]
# [('film', 'http://www.wikidata.org/entity/Q1633009'), ('name', 'The Little Matchgirl')]
# 3

# %% [markdown]
# `wd:Q944287` is The Little Mermaid

# %% [markdown]
# ## Task 7

# %%
queryString = """
SELECT DISTINCT ?people ?name
WHERE { 
    VALUES ?films {wd:Q944287 wd:Q36479}.
    # ?films ?prop ?people .
    # ?people wdt:P31 wd:Q5.
    # ?people sc:name ?name.
} 
GROUP BY ?people ?name
HAVING (COUNT (DISTINCT ?films) = 2 )
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('people', 'http://www.wikidata.org/entity/Q310292'), ('name', 'Jim Cummings')]
# 1

# %% [markdown]
# ## Task 8

# %%
queryString = """
SELECT DISTINCT ?pr ?name
WHERE {
    # ?film wdt:P272 wd:Q1047410 ;
          # ?pr ?o.
    # ?pr sc:name ?name.
} 
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('pr', 'http://www.wikidata.org/prop/direct/P3383'), ('name', 'film poster')]
# [('pr', 'http://www.wikidata.org/prop/direct/P7132'), ('name', 'ComingSoon.it film ID')]
# [('pr', 'http://www.wikidata.org/prop/direct/P2438'), ('name', 'narrator')]
# [('pr', 'http://www.wikidata.org/prop/direct/P3092'), ('name', 'film crew member')]
# [('pr', 'http://www.wikidata.org/prop/direct/P4021'), ('name', 'danskefilm animated film ID')]
# [('pr', 'http://www.wikidata.org/prop/direct/P5201'), ('name', 'IMDA rating')]
# [('pr', 'http://www.wikidata.org/prop/direct/P6359'), ('name', 'Crew United title ID')]
# [('pr', 'http://www.wikidata.org/prop/direct/P8371'), ('name', 'references work, tradition or theory')]
# [('pr', 'http://www.wikidata.org/prop/direct/P4437'), ('name', 'FPB rating')]
# [('pr', 'http://www.wikidata.org/prop/direct/P7679'), ('name', 'Cinépolis KLIC ID')]
# [('pr', 'http://www.wikidata.org/prop/direct/P8889'), ('name', 'MTRCB rating')]
# [('pr', 'http://www.wikidata.org/prop/direct/P7458'), ('name', 'Kinematoscope film ID')]
# [('pr', 'http://www.wikidata.org/prop/direct/P10'), ('name', 'video')]
# [('pr', 'http://www.wikidata.org/prop/direct/P1015'), ('name', 'NORAF ID')]
# [('pr', 'http://www.wikidata.org/prop/direct/P1040'), ('name', 'film editor')]
# [('pr', 'http://www.wikidata.org/prop/direct/P1113'), ('name', 'number of episodes')]
# [('pr', 'http://www.wikidata.org/prop/direct/P1237'), ('name', 'Box Office Mojo film ID (former scheme)')]
# [('pr', 'http://www.wikidata.org/prop/direct/P1258'), ('name', 'Rotten Tomatoes ID')]
# [('pr', 'http://www.wikidata.org/prop/direct/P1265'), ('name', 'AlloCiné film ID')]
# [('pr', 'http://www.wikidata.org/prop/direct/P1267'), ('name', 'AlloCiné series ID')]
# [('pr', 'http://www.wikidata.org/prop/direct/P1273'), ('name', 'CANTIC ID')]
# [('pr', 'http://www.wikidata.org/prop/direct/P136'), ('name', 'genre')]
# [('pr', 'http://www.wikidata.org/prop/direct/P138'), ('name', 'named after')]
# [('pr', 'http://www.wikidata.org/prop/direct/P1411'), ('name', 'nominated for')]
# [('pr', 'http://www.wikidata.org/prop/direct/P1417'), ('name', 'Encyclopædia Britannica Online ID')]
# [('pr', 'http://www.wikidata.org/prop/direct/P1434'), ('name', 'takes place in fictional universe')]
# [('pr', 'http://www.wikidata.org/prop/direct/P144'), ('name', 'based on')]
# [('pr', 'http://www.wikidata.org/prop/direct/P1476'), ('name', 'title')]
# [('pr', 'http://www.wikidata.org/prop/direct/P154'), ('name', 'logo image')]
# [('pr', 'http://www.wikidata.org/prop/direct/P155'), ('name', 'follows')]
# [('pr', 'http://www.wikidata.org/prop/direct/P1552'), ('name', 'has quality')]
# [('pr', 'http://www.wikidata.org/prop/direct/P156'), ('name', 'followed by')]
# [('pr', 'http://www.wikidata.org/prop/direct/P1562'), ('name', 'AllMovie title ID')]
# [('pr', 'http://www.wikidata.org/prop/direct/P161'), ('name', 'cast member')]
# [('pr', 'http://www.wikidata.org/prop/direct/P162'), ('name', 'producer')]
# [('pr', 'http://www.wikidata.org/prop/direct/P1651'), ('name', 'YouTube video ID')]
# [('pr', 'http://www.wikidata.org/prop/direct/P1657'), ('name', 'MPAA film rating')]
# [('pr', 'http://www.wikidata.org/prop/direct/P166'), ('name', 'award received')]
# [('pr', 'http://www.wikidata.org/prop/direct/P170'), ('name', 'creator')]
# [('pr', 'http://www.wikidata.org/prop/direct/P1712'), ('name', 'Metacritic ID')]
# [('pr', 'http://www.wikidata.org/prop/direct/P175'), ('name', 'performer')]
# [('pr', 'http://www.wikidata.org/prop/direct/P179'), ('name', 'part of the series')]
# [('pr', 'http://www.wikidata.org/prop/direct/P18'), ('name', 'image')]
# [('pr', 'http://www.wikidata.org/prop/direct/P180'), ('name', 'depicts')]
# [('pr', 'http://www.wikidata.org/prop/direct/P1804'), ('name', 'DNF film ID')]
# [('pr', 'http://www.wikidata.org/prop/direct/P1811'), ('name', 'list of episodes')]
# [('pr', 'http://www.wikidata.org/prop/direct/P1874'), ('name', 'Netflix ID')]
# [('pr', 'http://www.wikidata.org/prop/direct/P1881'), ('name', 'list of characters')]
# [('pr', 'http://www.wikidata.org/prop/direct/P1889'), ('name', 'different from')]
# [('pr', 'http://www.wikidata.org/prop/direct/P195'), ('name', 'collection')]
# [('pr', 'http://www.wikidata.org/prop/direct/P1970'), ('name', 'MovieMeter film ID')]
# [('pr', 'http://www.wikidata.org/prop/direct/P1981'), ('name', 'FSK film rating')]
# [('pr', 'http://www.wikidata.org/prop/direct/P2002'), ('name', 'Twitter username')]
# [('pr', 'http://www.wikidata.org/prop/direct/P2003'), ('name', 'Instagram username')]
# [('pr', 'http://www.wikidata.org/prop/direct/P2013'), ('name', 'Facebook ID')]
# [('pr', 'http://www.wikidata.org/prop/direct/P2047'), ('name', 'duration')]
# [('pr', 'http://www.wikidata.org/prop/direct/P2061'), ('name', 'aspect ratio')]
# [('pr', 'http://www.wikidata.org/prop/direct/P2079'), ('name', 'fabrication method')]
# [('pr', 'http://www.wikidata.org/prop/direct/P2130'), ('name', 'cost')]
# [('pr', 'http://www.wikidata.org/prop/direct/P214'), ('name', 'VIAF ID')]
# [('pr', 'http://www.wikidata.org/prop/direct/P2142'), ('name', 'box office')]
# [('pr', 'http://www.wikidata.org/prop/direct/P227'), ('name', 'GND ID')]
# [('pr', 'http://www.wikidata.org/prop/direct/P2283'), ('name', 'uses')]
# [('pr', 'http://www.wikidata.org/prop/direct/P2334'), ('name', 'Swedish Film Database film ID')]
# [('pr', 'http://www.wikidata.org/prop/direct/P2346'), ('name', 'Elonet movie ID')]
# [('pr', 'http://www.wikidata.org/prop/direct/P2363'), ('name', 'NMHH film rating')]
# [('pr', 'http://www.wikidata.org/prop/direct/P2364'), ('name', 'production code')]
# [('pr', 'http://www.wikidata.org/prop/direct/P2437'), ('name', 'number of seasons')]
# [('pr', 'http://www.wikidata.org/prop/direct/P244'), ('name', 'Library of Congress authority ID')]
# [('pr', 'http://www.wikidata.org/prop/direct/P2465'), ('name', 'Allcinema film ID')]
# [('pr', 'http://www.wikidata.org/prop/direct/P2508'), ('name', 'KINENOTE film ID')]
# [('pr', 'http://www.wikidata.org/prop/direct/P2509'), ('name', 'Movie Walker film ID')]
# [('pr', 'http://www.wikidata.org/prop/direct/P2512'), ('name', 'series spin-off')]
# [('pr', 'http://www.wikidata.org/prop/direct/P2515'), ('name', 'costume designer')]
# [('pr', 'http://www.wikidata.org/prop/direct/P2518'), ('name', 'Scope.dk film ID')]
# [('pr', 'http://www.wikidata.org/prop/direct/P2529'), ('name', 'ČSFD film ID')]
# [('pr', 'http://www.wikidata.org/prop/direct/P2581'), ('name', 'BabelNet ID')]
# [('pr', 'http://www.wikidata.org/prop/direct/P2603'), ('name', 'Kinopoisk film ID')]
# [('pr', 'http://www.wikidata.org/prop/direct/P2629'), ('name', 'BBFC rating')]
# [('pr', 'http://www.wikidata.org/prop/direct/P2631'), ('name', 'TCM Movie Database film ID')]
# [('pr', 'http://www.wikidata.org/prop/direct/P2635'), ('name', 'number of parts of this work')]
# [('pr', 'http://www.wikidata.org/prop/direct/P2636'), ('name', 'Minkultury film ID')]
# [('pr', 'http://www.wikidata.org/prop/direct/P2638'), ('name', 'TV.com ID')]
# [('pr', 'http://www.wikidata.org/prop/direct/P2639'), ('name', 'Filmportal ID')]
# [('pr', 'http://www.wikidata.org/prop/direct/P2671'), ('name', 'Google Knowledge Graph ID')]
# [('pr', 'http://www.wikidata.org/prop/direct/P268'), ('name', 'Bibliothèque nationale de France ID')]
# [('pr', 'http://www.wikidata.org/prop/direct/P269'), ('name', 'IdRef ID')]
# [('pr', 'http://www.wikidata.org/prop/direct/P2703'), ('name', 'BFI National Archive work ID')]
# [('pr', 'http://www.wikidata.org/prop/direct/P2704'), ('name', 'EIDR content ID')]
# [('pr', 'http://www.wikidata.org/prop/direct/P272'), ('name', 'production company')]
# [('pr', 'http://www.wikidata.org/prop/direct/P2747'), ('name', 'Filmiroda rating')]
# [('pr', 'http://www.wikidata.org/prop/direct/P2755'), ('name', 'exploitation visa number')]
# [('pr', 'http://www.wikidata.org/prop/direct/P2758'), ('name', 'CNC film rating (France)')]
# [('pr', 'http://www.wikidata.org/prop/direct/P2769'), ('name', 'budget')]
# [('pr', 'http://www.wikidata.org/prop/direct/P3077'), ('name', 'Cineplex Germany film ID')]
# [('pr', 'http://www.wikidata.org/prop/direct/P31'), ('name', 'instance of')]
# [('pr', 'http://www.wikidata.org/prop/direct/P3107'), ('name', 'LdiF ID')]
# [('pr', 'http://www.wikidata.org/prop/direct/P3110'), ('name', 'ISzDb film ID')]
# [('pr', 'http://www.wikidata.org/prop/direct/P3121'), ('name', 'Epguides ID')]
# [('pr', 'http://www.wikidata.org/prop/direct/P3129'), ('name', 'cine.gr film ID')]
# [('pr', 'http://www.wikidata.org/prop/direct/P3135'), ('name', 'elCinema film ID')]
# [('pr', 'http://www.wikidata.org/prop/direct/P3138'), ('name', 'OFDb film ID')]
# [('pr', 'http://www.wikidata.org/prop/direct/P3141'), ('name', 'EDb film ID')]
# [('pr', 'http://www.wikidata.org/prop/direct/P3143'), ('name', 'elFilm film ID')]
# [('pr', 'http://www.wikidata.org/prop/direct/P3145'), ('name', 'Sratim ID')]
# [('pr', 'http://www.wikidata.org/prop/direct/P3203'), ('name', 'Ciné-Ressources film ID')]
# [('pr', 'http://www.wikidata.org/prop/direct/P3212'), ('name', 'ISAN')]
# [('pr', 'http://www.wikidata.org/prop/direct/P3280'), ('name', 'BAnQ author ID')]
# [('pr', 'http://www.wikidata.org/prop/direct/P3301'), ('name', 'broadcast by')]
# [('pr', 'http://www.wikidata.org/prop/direct/P3302'), ('name', 'Open Media Database film ID')]
# [('pr', 'http://www.wikidata.org/prop/direct/P3306'), ('name', 'ICAA rating')]
# [('pr', 'http://www.wikidata.org/prop/direct/P3308'), ('name', 'lib.reviews ID')]
# [('pr', 'http://www.wikidata.org/prop/direct/P3340'), ('name', 'Kvikmyndir film ID')]
# [('pr', 'http://www.wikidata.org/prop/direct/P3402'), ('name', 'CNC film rating (Romania)')]
# [('pr', 'http://www.wikidata.org/prop/direct/P3417'), ('name', 'Quora topic ID')]
# [('pr', 'http://www.wikidata.org/prop/direct/P344'), ('name', 'director of photography')]
# [('pr', 'http://www.wikidata.org/prop/direct/P345'), ('name', 'IMDb ID')]
# [('pr', 'http://www.wikidata.org/prop/direct/P3509'), ('name', 'Dagens Nyheter topic ID')]
# [('pr', 'http://www.wikidata.org/prop/direct/P3553'), ('name', 'Zhihu topic ID')]
# [('pr', 'http://www.wikidata.org/prop/direct/P3593'), ('name', 'AFI Catalog of Feature Films ID')]
# [('pr', 'http://www.wikidata.org/prop/direct/P361'), ('name', 'part of')]
# [('pr', 'http://www.wikidata.org/prop/direct/P364'), ('name', 'original language of film or TV show')]
# [('pr', 'http://www.wikidata.org/prop/direct/P3650'), ('name', 'JMK film rating')]
# [('pr', 'http://www.wikidata.org/prop/direct/P373'), ('name', 'Commons category')]
# [('pr', 'http://www.wikidata.org/prop/direct/P3804'), ('name', 'TV Guide show ID (former scheme)')]
# [('pr', 'http://www.wikidata.org/prop/direct/P3808'), ('name', 'The Numbers movie ID')]
# [('pr', 'http://www.wikidata.org/prop/direct/P3834'), ('name', 'RTC film rating')]
# [('pr', 'http://www.wikidata.org/prop/direct/P3844'), ('name', 'Deutsche Synchronkartei film ID')]
# [('pr', 'http://www.wikidata.org/prop/direct/P3933'), ('name', 'Cinema.de ID')]
# [('pr', 'http://www.wikidata.org/prop/direct/P4013'), ('name', 'Giphy username')]
# [('pr', 'http://www.wikidata.org/prop/direct/P407'), ('name', 'language of work or name')]
# [('pr', 'http://www.wikidata.org/prop/direct/P4276'), ('name', 'Cinémathèque québécoise work identifier')]
# [('pr', 'http://www.wikidata.org/prop/direct/P4282'), ('name', 'LUMIERE film ID')]
# [('pr', 'http://www.wikidata.org/prop/direct/P437'), ('name', 'distribution format')]
# [('pr', 'http://www.wikidata.org/prop/direct/P4438'), ('name', 'BFI Films, TV and people ID')]
# [('pr', 'http://www.wikidata.org/prop/direct/P449'), ('name', 'original broadcaster')]
# [('pr', 'http://www.wikidata.org/prop/direct/P4515'), ('name', 'Prisma ID')]
# [('pr', 'http://www.wikidata.org/prop/direct/P4529'), ('name', 'Douban film ID')]
# [('pr', 'http://www.wikidata.org/prop/direct/P4619'), ('name', 'National Library of Brazil ID')]
# [('pr', 'http://www.wikidata.org/prop/direct/P462'), ('name', 'color')]
# [('pr', 'http://www.wikidata.org/prop/direct/P4632'), ('name', 'Bechdel Test Movie List ID')]
# [('pr', 'http://www.wikidata.org/prop/direct/P4665'), ('name', 'CineMagia title ID')]
# [('pr', 'http://www.wikidata.org/prop/direct/P4780'), ('name', 'MYmovies movie ID')]
# [('pr', 'http://www.wikidata.org/prop/direct/P4783'), ('name', 'Movieplayer film ID')]
# [('pr', 'http://www.wikidata.org/prop/direct/P4786'), ('name', 'cinematografo film ID')]
# [('pr', 'http://www.wikidata.org/prop/direct/P480'), ('name', 'FilmAffinity ID')]
# [('pr', 'http://www.wikidata.org/prop/direct/P4835'), ('name', 'TheTVDB.com series ID')]
# [('pr', 'http://www.wikidata.org/prop/direct/P4839'), ('name', 'Wolfram Language entity code')]
# [('pr', 'http://www.wikidata.org/prop/direct/P4947'), ('name', 'TMDb movie ID')]
# [('pr', 'http://www.wikidata.org/prop/direct/P495'), ('name', 'country of origin')]
# [('pr', 'http://www.wikidata.org/prop/direct/P4969'), ('name', 'derivative work')]
# [('pr', 'http://www.wikidata.org/prop/direct/P4983'), ('name', 'TMDb TV series ID')]
# [('pr', 'http://www.wikidata.org/prop/direct/P5021'), ('name', 'assessment')]
# [('pr', 'http://www.wikidata.org/prop/direct/P5032'), ('name', 'Filmweb.pl film ID')]
# [('pr', 'http://www.wikidata.org/prop/direct/P5099'), ('name', 'Il mondo dei doppiatori ID')]
# [('pr', 'http://www.wikidata.org/prop/direct/P5128'), ('name', 'ICAA film catalogue ID')]
# [('pr', 'http://www.wikidata.org/prop/direct/P5253'), ('name', 'FilmTv.it movie ID')]
# [('pr', 'http://www.wikidata.org/prop/direct/P527'), ('name', 'has part')]
# [('pr', 'http://www.wikidata.org/prop/direct/P5327'), ('name', 'fernsehserien.de ID')]
# [('pr', 'http://www.wikidata.org/prop/direct/P5357'), ('name', 'The Encyclopedia of Science Fiction ID')]
# [('pr', 'http://www.wikidata.org/prop/direct/P5693'), ('name', 'Fandango film ID')]
# [('pr', 'http://www.wikidata.org/prop/direct/P57'), ('name', 'director')]
# [('pr', 'http://www.wikidata.org/prop/direct/P5737'), ('name', 'Chinese Moegirlpedia ID')]
# [('pr', 'http://www.wikidata.org/prop/direct/P577'), ('name', 'publication date')]
# [('pr', 'http://www.wikidata.org/prop/direct/P5786'), ('name', 'Moviepilot.de film ID')]
# [('pr', 'http://www.wikidata.org/prop/direct/P58'), ('name', 'screenwriter')]
# [('pr', 'http://www.wikidata.org/prop/direct/P580'), ('name', 'start time')]
# [('pr', 'http://www.wikidata.org/prop/direct/P582'), ('name', 'end time')]
# [('pr', 'http://www.wikidata.org/prop/direct/P5885'), ('name', 'Microsoft Store product ID')]
# [('pr', 'http://www.wikidata.org/prop/direct/P5905'), ('name', 'Comic Vine ID')]
# [('pr', 'http://www.wikidata.org/prop/direct/P5925'), ('name', 'Moviepilot.de series ID')]
# [('pr', 'http://www.wikidata.org/prop/direct/P5970'), ('name', 'Medierådet rating')]
# [('pr', 'http://www.wikidata.org/prop/direct/P6127'), ('name', 'Letterboxd film ID')]
# [('pr', 'http://www.wikidata.org/prop/direct/P6145'), ('name', 'Academy Awards Database film ID')]
# [('pr', 'http://www.wikidata.org/prop/direct/P6181'), ('name', 'Disney A to Z ID')]
# [('pr', 'http://www.wikidata.org/prop/direct/P6262'), ('name', 'Fandom article ID')]
# [('pr', 'http://www.wikidata.org/prop/direct/P6398'), ('name', 'iTunes movie ID')]
# [('pr', 'http://www.wikidata.org/prop/direct/P646'), ('name', 'Freebase ID')]
# [('pr', 'http://www.wikidata.org/prop/direct/P6562'), ('name', 'Google Play Movies & TV ID')]
# [('pr', 'http://www.wikidata.org/prop/direct/P6584'), ('name', 'Scripts.com script ID')]
# [('pr', 'http://www.wikidata.org/prop/direct/P674'), ('name', 'characters')]
# [('pr', 'http://www.wikidata.org/prop/direct/P676'), ('name', 'lyrics by')]
# [('pr', 'http://www.wikidata.org/prop/direct/P6760'), ('name', 'Know Your Meme ID')]
# [('pr', 'http://www.wikidata.org/prop/direct/P6839'), ('name', 'TV Tropes identifier')]
# [('pr', 'http://www.wikidata.org/prop/direct/P6900'), ('name', 'NicoNicoPedia ID')]
# [('pr', 'http://www.wikidata.org/prop/direct/P7091'), ('name', 'Common Sense Media ID')]
# [('pr', 'http://www.wikidata.org/prop/direct/P7212'), ('name', 'LyricsTranslate ID')]
# [('pr', 'http://www.wikidata.org/prop/direct/P7222'), ('name', 'Eiga.com movie ID')]
# [('pr', 'http://www.wikidata.org/prop/direct/P7236'), ('name', 'Dove.org work ID')]
# [('pr', 'http://www.wikidata.org/prop/direct/P7293'), ('name', 'PLWABN ID')]
# [('pr', 'http://www.wikidata.org/prop/direct/P7299'), ('name', 'MUBI film ID')]
# [('pr', 'http://www.wikidata.org/prop/direct/P7334'), ('name', 'Vudu video ID')]
# [('pr', 'http://www.wikidata.org/prop/direct/P747'), ('name', 'has edition or translation')]
# [('pr', 'http://www.wikidata.org/prop/direct/P750'), ('name', 'distributed by')]
# [('pr', 'http://www.wikidata.org/prop/direct/P7818'), ('name', 'French Vikidia ID')]
# [('pr', 'http://www.wikidata.org/prop/direct/P793'), ('name', 'significant event')]
# [('pr', 'http://www.wikidata.org/prop/direct/P7970'), ('name', 'FandangoNow ID')]
# [('pr', 'http://www.wikidata.org/prop/direct/P8013'), ('name', 'Trakt.tv ID')]
# [('pr', 'http://www.wikidata.org/prop/direct/P8033'), ('name', 'Movie Review Query Engine ID')]
# [('pr', 'http://www.wikidata.org/prop/direct/P825'), ('name', 'dedicated to')]
# [('pr', 'http://www.wikidata.org/prop/direct/P8278'), ('name', 'serial identifier on SerialZone')]
# [('pr', 'http://www.wikidata.org/prop/direct/P8296'), ('name', 'Cinema Context ID')]
# [('pr', 'http://www.wikidata.org/prop/direct/P8345'), ('name', 'media franchise')]
# [('pr', 'http://www.wikidata.org/prop/direct/P840'), ('name', 'narrative location')]
# [('pr', 'http://www.wikidata.org/prop/direct/P8411'), ('name', 'set in environment')]
# [('pr', 'http://www.wikidata.org/prop/direct/P856'), ('name', 'official website')]
# [('pr', 'http://www.wikidata.org/prop/direct/P86'), ('name', 'composer')]
# [('pr', 'http://www.wikidata.org/prop/direct/P8687'), ('name', 'social media followers')]
# [('pr', 'http://www.wikidata.org/prop/direct/P8796'), ('name', 'FilmPolski press collection ID')]
# [('pr', 'http://www.wikidata.org/prop/direct/P8847'), ('name', 'Kinorium movie ID')]
# [('pr', 'http://www.wikidata.org/prop/direct/P905'), ('name', 'PORT film ID')]
# [('pr', 'http://www.wikidata.org/prop/direct/P910'), ('name', "topic's main category")]
# [('pr', 'http://www.wikidata.org/prop/direct/P915'), ('name', 'filming location')]
# [('pr', 'http://www.wikidata.org/prop/direct/P921'), ('name', 'main subject')]
# [('pr', 'http://www.wikidata.org/prop/direct/P935'), ('name', 'Commons gallery')]
# [('pr', 'http://www.wikidata.org/prop/direct/P941'), ('name', 'inspired by')]
# [('pr', 'http://www.wikidata.org/prop/direct/P950'), ('name', 'Biblioteca Nacional de España ID')]
# [('pr', 'http://www.wikidata.org/prop/direct/P9586'), ('name', 'Apple TV movie ID')]
# [('pr', 'http://www.wikidata.org/prop/direct/P973'), ('name', 'described at URL')]
# [('pr', 'http://www.wikidata.org/prop/direct/P2554'), ('name', 'production designer')]
# [('pr', 'http://www.wikidata.org/prop/direct/P1431'), ('name', 'executive producer')]
# [('pr', 'http://www.wikidata.org/prop/direct/P1877'), ('name', 'after a work by')]
# [('pr', 'http://www.wikidata.org/prop/direct/P2014'), ('name', 'Museum of Modern Art work ID')]
# [('pr', 'http://www.wikidata.org/prop/direct/P2408'), ('name', 'set in period')]
# [('pr', 'http://www.wikidata.org/prop/direct/P2684'), ('name', 'Kijkwijzer rating')]
# [('pr', 'http://www.wikidata.org/prop/direct/P3300'), ('name', 'musical conductor')]
# [('pr', 'http://www.wikidata.org/prop/direct/P3854'), ('name', 'Soundtrack Collector ID')]
# [('pr', 'http://www.wikidata.org/prop/direct/P3906'), ('name', 'Ishim ID')]
# [('pr', 'http://www.wikidata.org/prop/direct/P406'), ('name', 'soundtrack release')]
# [('pr', 'http://www.wikidata.org/prop/direct/P4277'), ('name', 'Daum movie ID')]
# [('pr', 'http://www.wikidata.org/prop/direct/P4834'), ('name', 'Deutsche Synchronkartei series ID')]
# [('pr', 'http://www.wikidata.org/prop/direct/P4933'), ('name', 'Big Cartoon Database ID')]
# [('pr', 'http://www.wikidata.org/prop/direct/P5150'), ('name', 'IGAC rating')]
# [('pr', 'http://www.wikidata.org/prop/direct/P5311'), ('name', 'Kino-teatr.ua film ID')]
# [('pr', 'http://www.wikidata.org/prop/direct/P5384'), ('name', 'Behind The Voice Actors film ID')]
# [('pr', 'http://www.wikidata.org/prop/direct/P5659'), ('name', 'VGMdb product ID')]
# [('pr', 'http://www.wikidata.org/prop/direct/P5990'), ('name', 'Movies Anywhere ID')]
# [('pr', 'http://www.wikidata.org/prop/direct/P6133'), ('name', 'Siamzone film ID')]
# [('pr', 'http://www.wikidata.org/prop/direct/P6643'), ('name', 'TV Spielfilm series ID')]
# [('pr', 'http://www.wikidata.org/prop/direct/P6949'), ('name', 'announcement date')]
# [('pr', 'http://www.wikidata.org/prop/direct/P7595'), ('name', 'Disney+ movie ID')]
# [('pr', 'http://www.wikidata.org/prop/direct/P7596'), ('name', 'Disney+ series ID')]
# [('pr', 'http://www.wikidata.org/prop/direct/P7975'), ('name', 'Filmfront film ID')]
# [('pr', 'http://www.wikidata.org/prop/direct/P8874'), ('name', 'Hong Kong film rating')]
# [('pr', 'http://www.wikidata.org/prop/direct/P9215'), ('name', 'set during recurring event')]
# [('pr', 'http://www.wikidata.org/prop/direct/P942'), ('name', 'theme music')]
# [('pr', 'http://www.wikidata.org/prop/direct/P2756'), ('name', 'EIRIN film rating')]
# [('pr', 'http://www.wikidata.org/prop/direct/P3174'), ('name', 'art director')]
# [('pr', 'http://www.wikidata.org/prop/direct/P7118'), ('name', 'AMPAS collections film ID')]
# [('pr', 'http://www.wikidata.org/prop/direct/P725'), ('name', 'voice actor')]
# [('pr', 'http://www.wikidata.org/prop/direct/P3818'), ('name', 'KMRB film rating')]
# [('pr', 'http://www.wikidata.org/prop/direct/P6658'), ('name', 'RCQ classification')]
# [('pr', 'http://www.wikidata.org/prop/direct/P2970'), ('name', 'Kinopolis film ID')]
# [('pr', 'http://www.wikidata.org/prop/direct/P3216'), ('name', 'ClassInd rating')]
# [('pr', 'http://www.wikidata.org/prop/direct/P3428'), ('name', 'INCAA film rating')]
# [('pr', 'http://www.wikidata.org/prop/direct/P7573'), ('name', 'IFCO rating')]
# [('pr', 'http://www.wikidata.org/prop/direct/P8958'), ('name', 'ClassInd audiovisual work ID')]
# [('pr', 'http://www.wikidata.org/prop/direct/P3275'), ('name', 'storyboard artist')]
# [('pr', 'http://www.wikidata.org/prop/direct/P4483'), ('name', 'INDUCKS story ID')]
# [('pr', 'http://www.wikidata.org/prop/direct/P6458'), ('name', 'Mtime movie ID')]
# [('pr', 'http://www.wikidata.org/prop/direct/P6942'), ('name', 'animator')]
# [('pr', 'http://www.wikidata.org/prop/direct/P7777'), ('name', 'AdoroCinema film ID')]
# [('pr', 'http://www.wikidata.org/prop/direct/P5387'), ('name', 'Behind The Voice Actors TV show ID')]
# [('pr', 'http://www.wikidata.org/prop/direct/P8918'), ('name', 'Max Movie film ID')]
# [('pr', 'http://www.wikidata.org/prop/direct/P9086'), ('name', 'BAMID film rating')]
# [('pr', 'http://www.wikidata.org/prop/direct/P3704'), ('name', 'KMDb film ID')]
# [('pr', 'http://www.wikidata.org/prop/direct/P1695'), ('name', 'NLP ID (unique)')]
# [('pr', 'http://www.wikidata.org/prop/direct/P2572'), ('name', 'hashtag')]
# [('pr', 'http://www.wikidata.org/prop/direct/P3478'), ('name', 'Songkick artist ID')]
# [('pr', 'http://www.wikidata.org/prop/direct/P436'), ('name', 'MusicBrainz release group ID')]
# [('pr', 'http://www.wikidata.org/prop/direct/P444'), ('name', 'review score')]
# [('pr', 'http://www.wikidata.org/prop/direct/P710'), ('name', 'participant')]
# [('pr', 'http://www.wikidata.org/prop/direct/P827'), ('name', 'BBC programme ID')]
# [('pr', 'http://www.wikidata.org/prop/direct/P9318'), ('name', 'Ávvir topic ID')]
# [('pr', 'http://www.wikidata.org/prop/direct/P1110'), ('name', 'attendance')]
# [('pr', 'http://www.wikidata.org/prop/direct/P1191'), ('name', 'date of first performance')]
# [('pr', 'http://www.wikidata.org/prop/direct/P3589'), ('name', 'GCD series ID')]
# [('pr', 'http://www.wikidata.org/prop/direct/P4647'), ('name', 'location of first performance')]
# [('pr', 'http://www.wikidata.org/prop/direct/P5338'), ('name', 'SilentEra.com film ID')]
# [('pr', 'http://www.wikidata.org/prop/direct/P7003'), ('name', 'ACMI web ID')]
# [('pr', 'http://www.wikidata.org/prop/direct/P7501'), ('name', 'audio system')]
# [('pr', 'http://www.wikidata.org/prop/direct/P2826'), ('name', 'Megogo ID')]
# [('pr', 'http://www.wikidata.org/prop/direct/P5865'), ('name', 'IGN film ID')]
# [('pr', 'http://www.wikidata.org/prop/direct/P6466'), ('name', 'Hulu movie ID')]
# [('pr', 'http://www.wikidata.org/prop/direct/P2637'), ('name', 'RARS rating')]
# [('pr', 'http://www.wikidata.org/prop/direct/P641'), ('name', 'sport')]
# [('pr', 'http://www.wikidata.org/prop/direct/P724'), ('name', 'Internet Archive ID')]
# 287

# %%
queryString = """
SELECT DISTINCT ?o ?name
WHERE {
    # ?film wdt:P272 wd:Q1047410 ;
          wdt:P166 ?o.
    # ?o sc:name ?name.
} 
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('o', 'http://www.wikidata.org/entity/Q135498'), ('name', 'Genesis Award')]
# [('o', 'http://www.wikidata.org/entity/Q1800189'), ('name', 'Annie Award for Best Animated Feature')]
# [('o', 'http://www.wikidata.org/entity/Q878902'), ('name', 'Golden Globe Award for Best Animated Feature Film')]
# [('o', 'http://www.wikidata.org/entity/Q917808'), ('name', 'Academy Award for Best Animated Short Film')]
# [('o', 'http://www.wikidata.org/entity/Q281939'), ('name', 'Academy Award for Best Film Editing')]
# [('o', 'http://www.wikidata.org/entity/Q823422'), ('name', 'National Film Registry')]
# [('o', 'http://www.wikidata.org/entity/Q393686'), ('name', 'Academy Award for Best Visual Effects')]
# [('o', 'http://www.wikidata.org/entity/Q488645'), ('name', 'Academy Award for Best Sound Editing')]
# [('o', 'http://www.wikidata.org/entity/Q488651'), ('name', 'Academy Award for Best Original Score')]
# [('o', 'http://www.wikidata.org/entity/Q106800'), ('name', 'Academy Award for Best Animated Feature')]
# [('o', 'http://www.wikidata.org/entity/Q2620855'), ('name', 'Satellite Award for Best Animated or Mixed Media Feature')]
# [('o', 'http://www.wikidata.org/entity/Q566905'), ('name', 'Annie Award')]
# [('o', 'http://www.wikidata.org/entity/Q922357'), ('name', "Critics' Choice Movie Award for Best Animated Feature")]
# [('o', 'http://www.wikidata.org/entity/Q1231643'), ('name', 'Saturn Award for Best Animated Film')]
# [('o', 'http://www.wikidata.org/entity/Q240201'), ('name', 'BAFTA Award for Best Animated Film')]
# [('o', 'http://www.wikidata.org/entity/Q494588'), ('name', 'Young Artist Award')]
# [('o', 'http://www.wikidata.org/entity/Q30327090'), ('name', 'Annecy Cristal for a Short Film')]
# 17

# %%
queryString = """
SELECT DISTINCT ?class ?name
WHERE {
    wd:Q106800 wdt:P31 ?class.
    # ?class sc:name ?name.
} 
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('class', 'http://www.wikidata.org/entity/Q96474688'), ('name', 'award for best film by genre')]
# [('class', 'http://www.wikidata.org/entity/Q19020'), ('name', 'Academy Awards')]
# 2

# %% [markdown]
# ## Task 9

# %%
queryString = """
SELECT ?film ?name (COUNT(DISTINCT ?rec) AS ?received)
WHERE {
    # ?film wdt:P272 wd:Q1047410 ;
          wdt:P166 ?rec.
    # ?rec wdt:P31 wd:Q19020.
    # ?film sc:name ?name.
} 
GROUP BY ?film ?name
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('film', 'http://www.wikidata.org/entity/Q246283'), ('name', 'Frozen'), ('received', '1')]
# [('film', 'http://www.wikidata.org/entity/Q36479'), ('name', 'The Lion King'), ('received', '1')]
# [('film', 'http://www.wikidata.org/entity/Q379873'), ('name', 'Who Framed Roger Rabbit'), ('received', '3')]
# [('film', 'http://www.wikidata.org/entity/Q16857388'), ('name', 'Feast'), ('received', '1')]
# [('film', 'http://www.wikidata.org/entity/Q13091172'), ('name', 'Big Hero 6'), ('received', '1')]
# [('film', 'http://www.wikidata.org/entity/Q2252695'), ('name', 'Paperman'), ('received', '1')]
# [('film', 'http://www.wikidata.org/entity/Q179673'), ('name', 'Beauty and the Beast'), ('received', '1')]
# [('film', 'http://www.wikidata.org/entity/Q15270647'), ('name', 'Zootopia'), ('received', '1')]
# 8

# %%
queryString = """
SELECT ?film ?name (COUNT(DISTINCT ?rec) AS ?received)
WHERE {
    # ?film wdt:P272 wd:Q1047410 ;
          wdt:P1411 ?rec.
    # ?rec wdt:P31 wd:Q19020.
    # ?film sc:name ?name.
} 
GROUP BY ?film ?name
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('film', 'http://www.wikidata.org/entity/Q246283'), ('name', 'Frozen'), ('received', '1')]
# [('film', 'http://www.wikidata.org/entity/Q36479'), ('name', 'The Lion King'), ('received', '1')]
# [('film', 'http://www.wikidata.org/entity/Q379873'), ('name', 'Who Framed Roger Rabbit'), ('received', '6')]
# [('film', 'http://www.wikidata.org/entity/Q16857388'), ('name', 'Feast'), ('received', '1')]
# [('film', 'http://www.wikidata.org/entity/Q18647981'), ('name', 'Moana'), ('received', '1')]
# [('film', 'http://www.wikidata.org/entity/Q2399982'), ('name', 'Tea for Two Hundred'), ('received', '1')]
# [('film', 'http://www.wikidata.org/entity/Q215617'), ('name', 'Sleeping Beauty'), ('received', '1')]
# [('film', 'http://www.wikidata.org/entity/Q212792'), ('name', 'Bolt'), ('received', '1')]
# [('film', 'http://www.wikidata.org/entity/Q28891'), ('name', 'Wreck-It Ralph'), ('received', '1')]
# [('film', 'http://www.wikidata.org/entity/Q640679'), ('name', 'Rugged Bear'), ('received', '1')]
# [('film', 'http://www.wikidata.org/entity/Q1440760'), ('name', 'Runaway Brain'), ('received', '1')]
# [('film', 'http://www.wikidata.org/entity/Q13091172'), ('name', 'Big Hero 6'), ('received', '1')]
# [('film', 'http://www.wikidata.org/entity/Q2252695'), ('name', 'Paperman'), ('received', '1')]
# [('film', 'http://www.wikidata.org/entity/Q3259450'), ('name', 'Lorenzo'), ('received', '1')]
# [('film', 'http://www.wikidata.org/entity/Q12124484'), ('name', 'Get a Horse!'), ('received', '1')]
# [('film', 'http://www.wikidata.org/entity/Q179673'), ('name', 'Beauty and the Beast'), ('received', '3')]
# [('film', 'http://www.wikidata.org/entity/Q213787'), ('name', 'The Hunchback of Notre Dame'), ('received', '1')]
# [('film', 'http://www.wikidata.org/entity/Q15270647'), ('name', 'Zootopia'), ('received', '1')]
# [('film', 'http://www.wikidata.org/entity/Q1633009'), ('name', 'The Little Matchgirl'), ('received', '1')]
# [('film', 'http://www.wikidata.org/entity/Q842306'), ('name', 'Saludos Amigos'), ('received', '2')]
# 20

# %%
queryString = """
SELECT ?film ?name ?received ?nomination
WHERE {
    {SELECT ?film ?name (COUNT(DISTINCT ?rec) AS ?nomination) WHERE{
        
        # ?rec wdt:P31 wd:Q19020.
        # ?film wdt:P272 wd:Q1047410 .
        # ?film sc:name ?name.
        OPTIONAL{
            # ?film wdt:P1411 ?rec.
        }
        
    }GROUP BY ?film ?name}
    {SELECT ?film ?name (COUNT(DISTINCT ?rec) AS ?received) WHERE{
        # ?rec wdt:P31 wd:Q19020.
        # ?film wdt:P272 wd:Q1047410 .
        # ?film sc:name ?name.
        OPTIONAL{
            # ?film wdt:P166 ?rec.
        }
        
    }GROUP BY ?film ?name}
} 
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('film', 'http://www.wikidata.org/entity/Q179673'), ('name', 'Beauty and the Beast'), ('received', '63'), ('nomination', '63')]
# [('film', 'http://www.wikidata.org/entity/Q97656754'), ('name', 'Zenimation'), ('received', '63'), ('nomination', '63')]
# [('film', 'http://www.wikidata.org/entity/Q28891'), ('name', 'Wreck-It Ralph'), ('received', '63'), ('nomination', '63')]
# [('film', 'http://www.wikidata.org/entity/Q3036139'), ('name', 'Beezy Bear'), ('received', '63'), ('nomination', '63')]
# [('film', 'http://www.wikidata.org/entity/Q1655222'), ('name', "Mickey's Once Upon a Christmas"), ('received', '63'), ('nomination', '63')]
# [('film', 'http://www.wikidata.org/entity/Q3236849'), ('name', "Let's Stick Together"), ('received', '63'), ('nomination', '63')]
# [('film', 'http://www.wikidata.org/entity/Q22350906'), ('name', 'Tummy Trouble'), ('received', '63'), ('nomination', '63')]
# [('film', 'http://www.wikidata.org/entity/Q2031788'), ('name', 'Tarzan & Jane'), ('received', '63'), ('nomination', '63')]
# [('film', 'http://www.wikidata.org/entity/Q4531204'), ('name', 'Elysium'), ('received', '63'), ('nomination', '63')]
# [('film', 'http://www.wikidata.org/entity/Q24733929'), ('name', 'Frozen II'), ('received', '63'), ('nomination', '63')]
# [('film', 'http://www.wikidata.org/entity/Q5282372'), ('name', "Disney's American Legends"), ('received', '63'), ('nomination', '63')]
# [('film', 'http://www.wikidata.org/entity/Q18398561'), ('name', 'Frozen Fever'), ('received', '63'), ('nomination', '63')]
# [('film', 'http://www.wikidata.org/entity/Q3362144'), ('name', 'Trail Mix-Up'), ('received', '63'), ('nomination', '63')]
# [('film', 'http://www.wikidata.org/entity/Q1440760'), ('name', 'Runaway Brain'), ('received', '63'), ('nomination', '63')]
# [('film', 'http://www.wikidata.org/entity/Q3036174'), ('name', 'Grin and Bear It'), ('received', '63'), ('nomination', '63')]
# [('film', 'http://www.wikidata.org/entity/Q30318729'), ('name', "Olaf's Frozen Adventure"), ('received', '63'), ('nomination', '63')]
# [('film', 'http://www.wikidata.org/entity/Q379873'), ('name', 'Who Framed Roger Rabbit'), ('received', '63'), ('nomination', '63')]
# [('film', 'http://www.wikidata.org/entity/Q246283'), ('name', 'Frozen'), ('received', '63'), ('nomination', '63')]
# [('film', 'http://www.wikidata.org/entity/Q3977989'), ('name', 'Supermodels'), ('received', '63'), ('nomination', '63')]
# [('film', 'http://www.wikidata.org/entity/Q223163'), ('name', "The Emperor's New Groove"), ('received', '63'), ('nomination', '63')]
# [('film', 'http://www.wikidata.org/entity/Q3771878'), ('name', "Glago's Guest"), ('received', '63'), ('nomination', '63')]
# [('film', 'http://www.wikidata.org/entity/Q179411'), ('name', 'A Very Merry Pooh Year'), ('received', '63'), ('nomination', '63')]
# [('film', 'http://www.wikidata.org/entity/Q30937'), ('name', 'Fantasia 2000'), ('received', '63'), ('nomination', '63')]
# [('film', 'http://www.wikidata.org/entity/Q12124484'), ('name', 'Get a Horse!'), ('received', '63'), ('nomination', '63')]
# [('film', 'http://www.wikidata.org/entity/Q944287'), ('name', 'The Little Mermaid'), ('received', '63'), ('nomination', '63')]
# [('film', 'http://www.wikidata.org/entity/Q221679'), ('name', 'Meet the Robinsons'), ('received', '63'), ('nomination', '63')]
# [('film', 'http://www.wikidata.org/entity/Q3520106'), ('name', 'The Brave Engineer'), ('received', '63'), ('nomination', '63')]
# [('film', 'http://www.wikidata.org/entity/Q2986130'), ('name', 'How to Hook Up Your Home Theater'), ('received', '63'), ('nomination', '63')]
# [('film', 'http://www.wikidata.org/entity/Q2252695'), ('name', 'Paperman'), ('received', '63'), ('nomination', '63')]
# [('film', 'http://www.wikidata.org/entity/Q215617'), ('name', 'Sleeping Beauty'), ('received', '63'), ('nomination', '63')]
# [('film', 'http://www.wikidata.org/entity/Q3259450'), ('name', 'Lorenzo'), ('received', '63'), ('nomination', '63')]
# [('film', 'http://www.wikidata.org/entity/Q213787'), ('name', 'The Hunchback of Notre Dame'), ('received', '63'), ('nomination', '63')]
# [('film', 'http://www.wikidata.org/entity/Q3977597'), ('name', 'Super Rhino'), ('received', '63'), ('nomination', '63')]
# [('film', 'http://www.wikidata.org/entity/Q7240601'), ('name', 'Prep & Landing'), ('received', '63'), ('nomination', '63')]
# [('film', 'http://www.wikidata.org/entity/Q25167044'), ('name', 'Ralph Breaks the Internet'), ('received', '63'), ('nomination', '63')]
# [('film', 'http://www.wikidata.org/entity/Q476329'), ('name', 'Dinosaur'), ('received', '63'), ('nomination', '63')]
# [('film', 'http://www.wikidata.org/entity/Q16857388'), ('name', 'Feast'), ('received', '63'), ('nomination', '63')]
# [('film', 'http://www.wikidata.org/entity/Q3028329'), ('name', 'Two Weeks Vacation'), ('received', '63'), ('nomination', '63')]
# [('film', 'http://www.wikidata.org/entity/Q3521221'), ('name', 'The Haunted House'), ('received', '63'), ('nomination', '63')]
# [('film', 'http://www.wikidata.org/entity/Q23925089'), ('name', 'Inner Workings'), ('received', '63'), ('nomination', '63')]
# [('film', 'http://www.wikidata.org/entity/Q3207087'), ('name', 'Hockey Homicide'), ('received', '63'), ('nomination', '63')]
# [('film', 'http://www.wikidata.org/entity/Q15270647'), ('name', 'Zootopia'), ('received', '63'), ('nomination', '63')]
# [('film', 'http://www.wikidata.org/entity/Q212792'), ('name', 'Bolt'), ('received', '63'), ('nomination', '63')]
# [('film', 'http://www.wikidata.org/entity/Q2275783'), ('name', 'The Barn Dance'), ('received', '63'), ('nomination', '63')]
# [('film', 'http://www.wikidata.org/entity/Q3006129'), ('name', 'Bearly Asleep'), ('received', '63'), ('nomination', '63')]
# [('film', 'http://www.wikidata.org/entity/Q2700743'), ('name', 'Clock Cleaners'), ('received', '63'), ('nomination', '63')]
# [('film', 'http://www.wikidata.org/entity/Q24970452'), ('name', 'Mickey Mouse Mixed-Up Adventures'), ('received', '63'), ('nomination', '63')]
# [('film', 'http://www.wikidata.org/entity/Q842306'), ('name', 'Saludos Amigos'), ('received', '63'), ('nomination', '63')]
# [('film', 'http://www.wikidata.org/entity/Q1633009'), ('name', 'The Little Matchgirl'), ('received', '63'), ('nomination', '63')]
# [('film', 'http://www.wikidata.org/entity/Q2090328'), ('name', 'Trick or Treat'), ('received', '63'), ('nomination', '63')]
# [('film', 'http://www.wikidata.org/entity/Q2399982'), ('name', 'Tea for Two Hundred'), ('received', '63'), ('nomination', '63')]
# [('film', 'http://www.wikidata.org/entity/Q66738105'), ('name', 'Raya and the Last Dragon'), ('received', '63'), ('nomination', '63')]
# [('film', 'http://www.wikidata.org/entity/Q202371'), ('name', 'The Rescuers Down Under'), ('received', '63'), ('nomination', '63')]
# [('film', 'http://www.wikidata.org/entity/Q107473453'), ('name', 'Searcher Clade'), ('received', '63'), ('nomination', '63')]
# [('film', 'http://www.wikidata.org/entity/Q15046569'), ('name', 'Roger Rabbit short films'), ('received', '63'), ('nomination', '63')]
# [('film', 'http://www.wikidata.org/entity/Q490464'), ('name', 'Enchanted'), ('received', '63'), ('nomination', '63')]
# [('film', 'http://www.wikidata.org/entity/Q36479'), ('name', 'The Lion King'), ('received', '63'), ('nomination', '63')]
# [('film', 'http://www.wikidata.org/entity/Q15545275'), ('name', 'Gigantic'), ('received', '63'), ('nomination', '63')]
# [('film', 'http://www.wikidata.org/entity/Q3178943'), ('name', "Donald's Dilemma"), ('received', '63'), ('nomination', '63')]
# [('film', 'http://www.wikidata.org/entity/Q869993'), ('name', 'A Goofy Movie'), ('received', '63'), ('nomination', '63')]
# [('film', 'http://www.wikidata.org/entity/Q20004165'), ('name', 'Roller Coaster Rabbit'), ('received', '63'), ('nomination', '63')]
# [('film', 'http://www.wikidata.org/entity/Q640679'), ('name', 'Rugged Bear'), ('received', '63'), ('nomination', '63')]
# [('film', 'http://www.wikidata.org/entity/Q8025669'), ('name', 'Winnie the Pooh Discovers the Seasons'), ('received', '63'), ('nomination', '63')]
# [('film', 'http://www.wikidata.org/entity/Q3392773'), ('name', 'Playful Pluto'), ('received', '63'), ('nomination', '63')]
# [('film', 'http://www.wikidata.org/entity/Q3228508'), ('name', 'Hold That Pose'), ('received', '63'), ('nomination', '63')]
# [('film', 'http://www.wikidata.org/entity/Q13091172'), ('name', 'Big Hero 6'), ('received', '63'), ('nomination', '63')]
# [('film', 'http://www.wikidata.org/entity/Q188439'), ('name', 'Tangled'), ('received', '63'), ('nomination', '63')]
# [('film', 'http://www.wikidata.org/entity/Q56112217'), ('name', 'Kingdom of the Sun'), ('received', '63'), ('nomination', '63')]
# [('film', 'http://www.wikidata.org/entity/Q494748'), ('name', 'Mickey Mouse Clubhouse'), ('received', '63'), ('nomination', '63')]
# [('film', 'http://www.wikidata.org/entity/Q22773153'), ('name', "Milo Murphy's Law"), ('received', '63'), ('nomination', '63')]
# [('film', 'http://www.wikidata.org/entity/Q270940'), ('name', 'Chicken Little'), ('received', '63'), ('nomination', '63')]
# [('film', 'http://www.wikidata.org/entity/Q18647981'), ('name', 'Moana'), ('received', '63'), ('nomination', '63')]
# [('film', 'http://www.wikidata.org/entity/Q751173'), ('name', 'The Ballad of Nessie'), ('received', '63'), ('nomination', '63')]
# 73

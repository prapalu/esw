# %% [markdown]
# # General instructions
#
# The goal of the project is to materialize a set of **exploratory workloads** over a real-world, large-scale,  open-domain KG: [WikiData](https://www.wikidata.org/wiki/Wikidata:Main_Page)
#
# An exploratory workload  is composed by a set of queries, where each query is related to the information obtained previously.
#
# An exploratory workload starts with a usually vague, open ended question, and does not assume the person issuing the workload has a clear understanding of the data contained in the target database or its structure.
#
# Remeber that:
#
# 1. All the queries must run in the python notebook
# 2. You can use classes and properties only if you find them via a SPARQL query that must be present in the notebook
# 3. You do not delete useless queries. Keep everything that is synthatically valid
#
# ```
# ?p <http://schema.org/name> ?name .
# ```
#
#     is the BGP returning a human-readable name of a property or a class in Wikidata.

# %%
## SETUP used later
import sys
import os
import json
import pandas as pd
sys.path.insert(1, '/locale/data/jupyter/prando/notebook/sparqlthesis/')
import modules.evaluation as evaluation
from SPARQLWrapper import SPARQLWrapper, JSON


prefixString = """
##-history5-##
PREFIX wd: <http://www.wikidata.org/entity/> 
PREFIX wdt: <http://www.wikidata.org/prop/direct/> 
PREFIX sc: <http://schema.org/>
"""

# select and construct queries
def run_query(queryString,verbose = True):
    to_run = prefixString + "\n" + queryString

    sparql = SPARQLWrapper("http://gracevirtuoso.dei.unipd.it/sparql")
    sparql.setTimeout(300)
    sparql.setReturnFormat(JSON)
    sparql.setQuery(to_run)

    try :
        results = sparql.query()
        json_results = results.convert()
        if len(json_results['results']['bindings'])==0:
            print("Empty")
            return []
        array = []
        for bindings in json_results['results']['bindings']:
            app =  [ (var, value['value'])  for var, value in bindings.items() ] 
            if verbose:
                print( app)
            array.append(app)
        if verbose:
            print(len(array))
        return array

    except Exception as e :
        print("The operation failed", e)
    
# ASk queries
def run_ask_query(queryString):
    to_run = prefixString + "\n" + queryString

    sparql = SPARQLWrapper("http://gracevirtuoso.dei.unipd.it/sparql")
    sparql.setTimeout(300)
    sparql.setReturnFormat(JSON)
    sparql.setQuery(to_run)

    try :
        return sparql.query().convert()

    except Exception as e :
        print("The operation failed", e)

# %% [markdown]
# # History Workflow Series ("Euro explorative search")
#
# Consider the following exploratory information need:
#
# > investigate the Euro currency, which are the countries that currently use the Euro and which were their currencies before the Euro. Take a look also to other currencies and find which are the most used.

# %% [markdown]
# ## Useful URIs for the current workflow
# The following are given:
#
# | IRI           | Description   | Role      |
# | -----------   | -----------   |-----------|
# | `wdt:P1647`   | subproperty   | predicate |
# | `wdt:P31`     | instance of   | predicate |
# | `wdt:P106`    | occupation    | predicate |
# | `wdt:P279`    | subclass      | predicate |
# | `wdt:P27`     | nationality   | predicate |
# | `wd:Q5`| Human       | node |
# | `wd:Q38`| Italy   | node |

# %% [markdown]
# Also consider
#
# ```
# wd:Q38 ?p ?obj .
# ```
#
# is the BGP to retrieve all **properties of Italy**
#
# Please consider that when you return a resource, you should return the IRI and the label of the resource. In particular, when the task require you to identify a BGP the result set must always be a list of couples IRI - label.
#
#
#
# The workload should:
#
#
# 1. Identify the BGP for currency
#
# 2. Return the countries which currently use Euro
#
# 3. Return the countries belonging to the European Union, with a currency different from the Euro (return also their currency).
#
# 4. For each country that now uses Euro return which was the currencies used before
#
# 5. Return all types of dollar in the world (US Dollar, Australian Dollar, ecc...)
#
# 6. Return the currencies used in at least 2 different countries (return also the number of countries using each currency).
#
# 7. Consider the currencies obtained in task 6, for each currency return the number of people using that currency (hint: consider the maximum popolation available for each country).

# %%
## startup the evaluation
# setup the file and create the empty json
ipname = "h5.ipynb"
pt = os.getcwd()+os.sep+ipname
evaluation.setup(pt)
# Out:
# The index of this workflow is: 1_1

# %% [markdown]
# ## Task 1

# %%
# find properties of Italy
queryString = """
SELECT DISTINCT ?p ?name
WHERE { 
    wd:Q38 ?p ?obj.
    # ?p sc:name ?name.
} 
order by ?name
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('p', 'http://www.wikidata.org/prop/direct/P8061'), ('name', 'AGROVOC ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5198'), ('name', 'ASC Leiden Thesaurus ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6150'), ('name', 'Academy Awards Database nominee ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8895'), ('name', 'All the Tropes identifier')]
# [('p', 'http://www.wikidata.org/prop/direct/P7870'), ('name', 'Analysis & Policy Observatory term ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8785'), ('name', 'AniDB tag ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P9629'), ('name', 'Armeniapedia ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6200'), ('name', 'BBC News topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1617'), ('name', 'BBC Things ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P9037'), ('name', 'BHCL UUID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2581'), ('name', 'BabelNet ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7832'), ('name', 'Basque Vikidia ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5019'), ('name', 'Brockhaus Enzyklopädie online ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5180'), ('name', 'CIVICUS Monitor country entry')]
# [('p', 'http://www.wikidata.org/prop/direct/P9368'), ('name', 'CNA topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P9123'), ('name', 'Catalan Vikidia ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5905'), ('name', 'Comic Vine ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P373'), ('name', 'Commons category')]
# [('p', 'http://www.wikidata.org/prop/direct/P935'), ('name', 'Commons gallery')]
# [('p', 'http://www.wikidata.org/prop/direct/P998'), ('name', 'Curlie ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6849'), ('name', 'DR topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3509'), ('name', 'Dagens Nyheter topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1036'), ('name', 'Dewey Decimal Classification')]
# [('p', 'http://www.wikidata.org/prop/direct/P4589'), ('name', 'Dreadnought Project page')]
# [('p', 'http://www.wikidata.org/prop/direct/P4672'), ('name', 'EMLO location ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P9545'), ('name', 'Encyclopedia of China Online Database ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P4613'), ('name', 'Encyclopedia of Modern Ukraine ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8935'), ('name', 'Encyclopedia of the History of Ukraine ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8472'), ('name', 'Encyclopedie berbere keyword ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1417'), ('name', 'Encyclopædia Britannica Online ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3219'), ('name', 'Encyclopædia Universalis ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7829'), ('name', 'English Vikidia ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5437'), ('name', 'EuroVoc ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2163'), ('name', 'FAST ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P901'), ('name', 'FIPS 10-4 (countries and regions)')]
# [('p', 'http://www.wikidata.org/prop/direct/P6262'), ('name', 'Fandom article ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P4073'), ('name', 'Fandom wiki ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P646'), ('name', 'Freebase ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7818'), ('name', 'French Vikidia ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P4427'), ('name', 'GACS ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P227'), ('name', 'GND ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3067'), ('name', 'GS1 country code')]
# [('p', 'http://www.wikidata.org/prop/direct/P5400'), ('name', 'GeoNLP ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1566'), ('name', 'GeoNames ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1667'), ('name', 'Getty Thesaurus of Geographic Names ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5247'), ('name', 'Giant Bomb ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P9100'), ('name', 'GitHub topic')]
# [('p', 'http://www.wikidata.org/prop/direct/P1842'), ('name', 'Global Anabaptist Mennonite Encyclopedia Online ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1296'), ('name', 'Gran Enciclopèdia Catalana ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2924'), ('name', 'Great Russian Encyclopedia Online ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7295'), ('name', 'Gregorian calendar start date')]
# [('p', 'http://www.wikidata.org/prop/direct/P8406'), ('name', 'Grove Art Online ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3106'), ('name', 'Guardian topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5843'), ('name', 'Gynopedia ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P902'), ('name', 'HDS ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7982'), ('name', 'Hrvatska enciklopedija ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1081'), ('name', 'Human Development Index')]
# [('p', 'http://www.wikidata.org/prop/direct/P5250'), ('name', 'IAB code')]
# [('p', 'http://www.wikidata.org/prop/direct/P3422'), ('name', 'INSEE countries and foreign territories code')]
# [('p', 'http://www.wikidata.org/prop/direct/P984'), ('name', 'IOC country code')]
# [('p', 'http://www.wikidata.org/prop/direct/P898'), ('name', 'IPA transcription')]
# [('p', 'http://www.wikidata.org/prop/direct/P3097'), ('name', 'ISBN identifier group')]
# [('p', 'http://www.wikidata.org/prop/direct/P213'), ('name', 'ISNI')]
# [('p', 'http://www.wikidata.org/prop/direct/P297'), ('name', 'ISO 3166-1 alpha-2 code')]
# [('p', 'http://www.wikidata.org/prop/direct/P298'), ('name', 'ISO 3166-1 alpha-3 code')]
# [('p', 'http://www.wikidata.org/prop/direct/P299'), ('name', 'ISO 3166-1 numeric code')]
# [('p', 'http://www.wikidata.org/prop/direct/P3024'), ('name', 'ITU letter code')]
# [('p', 'http://www.wikidata.org/prop/direct/P3743'), ('name', 'ITU/ISO/IEC object identifier')]
# [('p', 'http://www.wikidata.org/prop/direct/P5063'), ('name', 'Interlingual Index ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5698'), ('name', 'Invasive Species Compendium Datasheet ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7822'), ('name', 'Italian Vikidia ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6413'), ('name', 'JORFSearch organization ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1438'), ('name', 'Jewish Encyclopedia ID (Russian)')]
# [('p', 'http://www.wikidata.org/prop/direct/P7960'), ('name', 'Joconde discovery ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7850'), ('name', 'Joconde location ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8408'), ('name', 'KBpedia ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6573'), ('name', 'Klexikon article ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3612'), ('name', 'Le Monde diplomatique subject ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7208'), ('name', 'Liber Liber author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P244'), ('name', 'Library of Congress authority ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P4801'), ('name', 'LoC and MARC vocabularies ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7322'), ('name', 'Marine Regions Geographic IDentifier (MRGID)')]
# [('p', 'http://www.wikidata.org/prop/direct/P486'), ('name', 'MeSH descriptor ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P982'), ('name', 'MusicBrainz area ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2004'), ('name', 'NALT ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3222'), ('name', 'NE.se ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P691'), ('name', 'NKCR AUT ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P605'), ('name', 'NUTS code')]
# [('p', 'http://www.wikidata.org/prop/direct/P8885'), ('name', 'Namuwiki ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P349'), ('name', 'National Diet Library ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P949'), ('name', 'National Library of Israel ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3221'), ('name', 'New York Times topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2950'), ('name', 'Nomisma ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1245'), ('name', 'OmegaWiki Defined Meaning')]
# [('p', 'http://www.wikidata.org/prop/direct/P3479'), ('name', 'Omni topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P402'), ('name', 'OpenStreetMap relation ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6592'), ('name', 'OpenStreetMap zoom level')]
# [('p', 'http://www.wikidata.org/prop/direct/P5002'), ('name', 'Orthodox Encyclopedia ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P5739'), ('name', 'Pontificia Università della Santa Croce ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P1005'), ('name', 'Portuguese National Library ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8349'), ('name', 'Proleksis enciklopedija ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P9223'), ('name', 'Provenio UUID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3417'), ('name', 'Quora topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8519'), ('name', 'RKD thesaurus ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8974'), ('name', 'SAPA ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3987'), ('name', 'SHARE Catalogue author ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3911'), ('name', 'STW Thesaurus for Economics ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P9757'), ('name', 'Schoenberg Database of Manuscripts place ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7827'), ('name', 'Spanish Vikidia ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P9122'), ('name', 'SportsLogos.net team ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3175'), ('name', 'Statoids ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P4342'), ('name', 'Store norske leksikon ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7314'), ('name', 'TDV İslam Ansiklopedisi ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6839'), ('name', 'TV Tropes identifier')]
# [('p', 'http://www.wikidata.org/prop/direct/P5456'), ('name', 'TasteAtlas ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7157'), ('name', 'The Top Tens ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3365'), ('name', 'Treccani ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6404'), ('name', "Treccani's Dizionario di Storia ID")]
# [('p', 'http://www.wikidata.org/prop/direct/P1225'), ('name', 'U.S. National Archives Identifier')]
# [('p', 'http://www.wikidata.org/prop/direct/P2981'), ('name', 'UIC alphabetical country code')]
# [('p', 'http://www.wikidata.org/prop/direct/P2982'), ('name', 'UIC numerical country code')]
# [('p', 'http://www.wikidata.org/prop/direct/P4527'), ('name', 'UK Parliament thesaurus ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3916'), ('name', 'UNESCO Thesaurus ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P487'), ('name', 'Unicode character')]
# [('p', 'http://www.wikidata.org/prop/direct/P2855'), ('name', 'VAT-rate')]
# [('p', 'http://www.wikidata.org/prop/direct/P214'), ('name', 'VIAF ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3068'), ('name', 'WIPO ST.3')]
# [('p', 'http://www.wikidata.org/prop/direct/P6766'), ('name', "Who's on First ID")]
# [('p', 'http://www.wikidata.org/prop/direct/P5125'), ('name', 'Wikimedia outline')]
# [('p', 'http://www.wikidata.org/prop/direct/P8814'), ('name', 'WordNet 3.1 Synset ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7012'), ('name', 'World Encyclopedia of Puppetry Arts ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7859'), ('name', 'WorldCat Identities ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P6293'), ('name', 'YSA ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2347'), ('name', 'YSO ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8309'), ('name', 'Yle topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P3553'), ('name', 'Zhihu topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2997'), ('name', 'age of majority')]
# [('p', 'http://www.wikidata.org/prop/direct/P85'), ('name', 'anthem')]
# [('p', 'http://www.wikidata.org/prop/direct/P5573'), ('name', 'archINFORM location ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2046'), ('name', 'area')]
# [('p', 'http://www.wikidata.org/prop/direct/P122'), ('name', 'basic form of government')]
# [('p', 'http://www.wikidata.org/prop/direct/P36'), ('name', 'capital')]
# [('p', 'http://www.wikidata.org/prop/direct/P1740'), ('name', 'category for films shot at this location')]
# [('p', 'http://www.wikidata.org/prop/direct/P7867'), ('name', 'category for maps')]
# [('p', 'http://www.wikidata.org/prop/direct/P1465'), ('name', 'category for people who died here')]
# [('p', 'http://www.wikidata.org/prop/direct/P1464'), ('name', 'category for people born here')]
# [('p', 'http://www.wikidata.org/prop/direct/P1792'), ('name', 'category of associated people')]
# [('p', 'http://www.wikidata.org/prop/direct/P1791'), ('name', 'category of people buried here')]
# [('p', 'http://www.wikidata.org/prop/direct/P237'), ('name', 'coat of arms')]
# [('p', 'http://www.wikidata.org/prop/direct/P94'), ('name', 'coat of arms image')]
# [('p', 'http://www.wikidata.org/prop/direct/P3271'), ('name', 'compulsory education (maximum age)')]
# [('p', 'http://www.wikidata.org/prop/direct/P3270'), ('name', 'compulsory education (minimum age)')]
# [('p', 'http://www.wikidata.org/prop/direct/P150'), ('name', 'contains administrative territorial entity')]
# [('p', 'http://www.wikidata.org/prop/direct/P30'), ('name', 'continent')]
# [('p', 'http://www.wikidata.org/prop/direct/P17'), ('name', 'country')]
# [('p', 'http://www.wikidata.org/prop/direct/P474'), ('name', 'country calling code')]
# [('p', 'http://www.wikidata.org/prop/direct/P2596'), ('name', 'culture')]
# [('p', 'http://www.wikidata.org/prop/direct/P38'), ('name', 'currency')]
# [('p', 'http://www.wikidata.org/prop/direct/P9241'), ('name', 'demographics of topic')]
# [('p', 'http://www.wikidata.org/prop/direct/P1549'), ('name', 'demonym')]
# [('p', 'http://www.wikidata.org/prop/direct/P1343'), ('name', 'described by source')]
# [('p', 'http://www.wikidata.org/prop/direct/P530'), ('name', 'diplomatic relation')]
# [('p', 'http://www.wikidata.org/prop/direct/P1622'), ('name', 'driving side')]
# [('p', 'http://www.wikidata.org/prop/direct/P8744'), ('name', 'economy of topic')]
# [('p', 'http://www.wikidata.org/prop/direct/P8826'), ('name', 'edition humboldt digital ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P2853'), ('name', 'electrical plug type')]
# [('p', 'http://www.wikidata.org/prop/direct/P2852'), ('name', 'emergency telephone number')]
# [('p', 'http://www.wikidata.org/prop/direct/P208'), ('name', 'executive body')]
# [('p', 'http://www.wikidata.org/prop/direct/P163'), ('name', 'flag')]
# [('p', 'http://www.wikidata.org/prop/direct/P41'), ('name', 'flag image')]
# [('p', 'http://www.wikidata.org/prop/direct/P155'), ('name', 'follows')]
# [('p', 'http://www.wikidata.org/prop/direct/P2633'), ('name', 'geography of topic')]
# [('p', 'http://www.wikidata.org/prop/direct/P3896'), ('name', 'geoshape')]
# [('p', 'http://www.wikidata.org/prop/direct/P1552'), ('name', 'has quality')]
# [('p', 'http://www.wikidata.org/prop/direct/P6'), ('name', 'head of government')]
# [('p', 'http://www.wikidata.org/prop/direct/P35'), ('name', 'head of state')]
# [('p', 'http://www.wikidata.org/prop/direct/P209'), ('name', 'highest judicial authority')]
# [('p', 'http://www.wikidata.org/prop/direct/P610'), ('name', 'highest point')]
# [('p', 'http://www.wikidata.org/prop/direct/P2184'), ('name', 'history of topic')]
# [('p', 'http://www.wikidata.org/prop/direct/P8217'), ('name', 'iDAI.gazetteer ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P7471'), ('name', 'iNaturalist place ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P571'), ('name', 'inception')]
# [('p', 'http://www.wikidata.org/prop/direct/P31'), ('name', 'instance of')]
# [('p', 'http://www.wikidata.org/prop/direct/P2936'), ('name', 'language used')]
# [('p', 'http://www.wikidata.org/prop/direct/P194'), ('name', 'legislative body')]
# [('p', 'http://www.wikidata.org/prop/direct/P395'), ('name', 'licence plate code')]
# [('p', 'http://www.wikidata.org/prop/direct/P2250'), ('name', 'life expectancy')]
# [('p', 'http://www.wikidata.org/prop/direct/P206'), ('name', 'located in or next to body of water')]
# [('p', 'http://www.wikidata.org/prop/direct/P421'), ('name', 'located in time zone')]
# [('p', 'http://www.wikidata.org/prop/direct/P706'), ('name', 'located in/on physical feature')]
# [('p', 'http://www.wikidata.org/prop/direct/P242'), ('name', 'locator map image')]
# [('p', 'http://www.wikidata.org/prop/direct/P1589'), ('name', 'lowest point')]
# [('p', 'http://www.wikidata.org/prop/direct/P92'), ('name', 'main regulatory text')]
# [('p', 'http://www.wikidata.org/prop/direct/P2884'), ('name', 'mains voltage')]
# [('p', 'http://www.wikidata.org/prop/direct/P6104'), ('name', 'maintained by WikiProject')]
# [('p', 'http://www.wikidata.org/prop/direct/P2979'), ('name', 'maritime identification digits')]
# [('p', 'http://www.wikidata.org/prop/direct/P3000'), ('name', 'marriageable age')]
# [('p', 'http://www.wikidata.org/prop/direct/P3529'), ('name', 'median income')]
# [('p', 'http://www.wikidata.org/prop/direct/P463'), ('name', 'member of')]
# [('p', 'http://www.wikidata.org/prop/direct/P7422'), ('name', 'minimum temperature record')]
# [('p', 'http://www.wikidata.org/prop/direct/P2258'), ('name', 'mobile country code')]
# [('p', 'http://www.wikidata.org/prop/direct/P1451'), ('name', 'motto text')]
# [('p', 'http://www.wikidata.org/prop/direct/P1120'), ('name', 'number of deaths')]
# [('p', 'http://www.wikidata.org/prop/direct/P2573'), ('name', 'number of out-of-school children')]
# [('p', 'http://www.wikidata.org/prop/direct/P1906'), ('name', 'office held by head of state')]
# [('p', 'http://www.wikidata.org/prop/direct/P1313'), ('name', 'office held by head of government')]
# [('p', 'http://www.wikidata.org/prop/direct/P37'), ('name', 'official language')]
# [('p', 'http://www.wikidata.org/prop/direct/P856'), ('name', 'official website')]
# [('p', 'http://www.wikidata.org/prop/direct/P5008'), ('name', 'on focus list of Wikimedia project')]
# [('p', 'http://www.wikidata.org/prop/direct/P8402'), ('name', 'open data portal')]
# [('p', 'http://www.wikidata.org/prop/direct/P948'), ('name', 'page banner')]
# [('p', 'http://www.wikidata.org/prop/direct/P361'), ('name', 'part of')]
# [('p', 'http://www.wikidata.org/prop/direct/P417'), ('name', 'patron saint')]
# [('p', 'http://www.wikidata.org/prop/direct/P2959'), ('name', 'permanent duplicated item')]
# [('p', 'http://www.wikidata.org/prop/direct/P1082'), ('name', 'population')]
# [('p', 'http://www.wikidata.org/prop/direct/P443'), ('name', 'pronunciation audio')]
# [('p', 'http://www.wikidata.org/prop/direct/P832'), ('name', 'public holiday')]
# [('p', 'http://www.wikidata.org/prop/direct/P5658'), ('name', 'railway traffic side')]
# [('p', 'http://www.wikidata.org/prop/direct/P1365'), ('name', 'replaces')]
# [('p', 'http://www.wikidata.org/prop/direct/P1419'), ('name', 'shape')]
# [('p', 'http://www.wikidata.org/prop/direct/P47'), ('name', 'shares border with')]
# [('p', 'http://www.wikidata.org/prop/direct/P3984'), ('name', 'subreddit')]
# [('p', 'http://www.wikidata.org/prop/direct/P78'), ('name', 'top-level Internet domain')]
# [('p', 'http://www.wikidata.org/prop/direct/P1151'), ('name', "topic's main Wikimedia portal")]
# [('p', 'http://www.wikidata.org/prop/direct/P910'), ('name', "topic's main category")]
# [('p', 'http://www.wikidata.org/prop/direct/P4841'), ('name', 'total fertility rate')]
# [('p', 'http://www.wikidata.org/prop/direct/P1198'), ('name', 'unemployment rate')]
# [('p', 'http://www.wikidata.org/prop/direct/P2436'), ('name', 'voltage')]
# [('p', 'http://www.wikidata.org/prop/direct/P9318'), ('name', 'Ávvir topic ID')]
# [('p', 'http://www.wikidata.org/prop/direct/P8432'), ('name', 'Österreichisches Musiklexikon Online ID')]
# 230

# %%
# use the property currency
queryString = """
SELECT DISTINCT ?obj ?name
WHERE { 
    wd:Q38 wdt:P38 ?obj.
    # ?obj sc:name ?name.
}
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('obj', 'http://www.wikidata.org/entity/Q4916'), ('name', 'euro')]
# 1

# %%
# instance of
queryString = """
SELECT DISTINCT ?obj ?name
WHERE { 
    wd:Q4916 wdt:P31 ?obj.
    # ?obj sc:name ?name.
}
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('obj', 'http://www.wikidata.org/entity/Q8142'), ('name', 'currency')]
# [('obj', 'http://www.wikidata.org/entity/Q28795800'), ('name', 'decimal currency')]
# 2

# %%
### insert the result of TASK 1 in the file
og_uri = "http://www.wikidata.org/entity/Q8142"
og_name = "currency"
obj = {"uri":og_uri,"name":og_name}
evaluation.add_result(evaluation.get_index_workflow(pt),"1", evaluation.TYPE_SINGLE ,"uri", [obj] ,"all")
# Out:
# The index of this workflow is: 1_1
# The path is /locale/data/jupyter/prando/notebook/2022/results/workflow1_1.json
# JSON object updated

# %% [markdown]
# `wd:Q8142` is the class of currency

# %% [markdown]
# ## Task 2

# %%
# properties of euro
queryString = """
SELECT DISTINCT ?prop ?name
WHERE { 
    wd:Q4916 ?prop ?obj.
    # ?prop sc:name ?name.
}
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('prop', 'http://www.wikidata.org/prop/direct/P1001'), ('name', 'applies to jurisdiction')]
# [('prop', 'http://www.wikidata.org/prop/direct/P1245'), ('name', 'OmegaWiki Defined Meaning')]
# [('prop', 'http://www.wikidata.org/prop/direct/P1282'), ('name', 'OpenStreetMap tag or key')]
# [('prop', 'http://www.wikidata.org/prop/direct/P1365'), ('name', 'replaces')]
# [('prop', 'http://www.wikidata.org/prop/direct/P138'), ('name', 'named after')]
# [('prop', 'http://www.wikidata.org/prop/direct/P1417'), ('name', 'Encyclopædia Britannica Online ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P1482'), ('name', 'Stack Exchange tag')]
# [('prop', 'http://www.wikidata.org/prop/direct/P154'), ('name', 'logo image')]
# [('prop', 'http://www.wikidata.org/prop/direct/P166'), ('name', 'award received')]
# [('prop', 'http://www.wikidata.org/prop/direct/P17'), ('name', 'country')]
# [('prop', 'http://www.wikidata.org/prop/direct/P18'), ('name', 'image')]
# [('prop', 'http://www.wikidata.org/prop/direct/P1813'), ('name', 'short name')]
# [('prop', 'http://www.wikidata.org/prop/direct/P1889'), ('name', 'different from')]
# [('prop', 'http://www.wikidata.org/prop/direct/P1993'), ('name', 'TeX string')]
# [('prop', 'http://www.wikidata.org/prop/direct/P227'), ('name', 'GND ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P2284'), ('name', 'price')]
# [('prop', 'http://www.wikidata.org/prop/direct/P2347'), ('name', 'YSO ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P244'), ('name', 'Library of Congress authority ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P2442'), ('name', 'conversion to standard unit')]
# [('prop', 'http://www.wikidata.org/prop/direct/P268'), ('name', 'Bibliothèque nationale de France ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P279'), ('name', 'subclass of')]
# [('prop', 'http://www.wikidata.org/prop/direct/P2888'), ('name', 'exact match')]
# [('prop', 'http://www.wikidata.org/prop/direct/P2924'), ('name', 'Great Russian Encyclopedia Online ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P2959'), ('name', 'permanent duplicated item')]
# [('prop', 'http://www.wikidata.org/prop/direct/P2968'), ('name', 'QUDT unit ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P31'), ('name', 'instance of')]
# [('prop', 'http://www.wikidata.org/prop/direct/P3219'), ('name', 'Encyclopædia Universalis ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P3328'), ('name', 'wurvoc.org measure ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P3347'), ('name', 'PermID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P3417'), ('name', 'Quora topic ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P349'), ('name', 'National Diet Library ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P3553'), ('name', 'Zhihu topic ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P3569'), ('name', 'Cultureel Woordenboek ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P373'), ('name', 'Commons category')]
# [('prop', 'http://www.wikidata.org/prop/direct/P3911'), ('name', 'STW Thesaurus for Economics ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P4527'), ('name', 'UK Parliament thesaurus ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P487'), ('name', 'Unicode character')]
# [('prop', 'http://www.wikidata.org/prop/direct/P489'), ('name', 'currency symbol description')]
# [('prop', 'http://www.wikidata.org/prop/direct/P498'), ('name', 'ISO 4217 code')]
# [('prop', 'http://www.wikidata.org/prop/direct/P5008'), ('name', 'on focus list of Wikimedia project')]
# [('prop', 'http://www.wikidata.org/prop/direct/P5019'), ('name', 'Brockhaus Enzyklopädie online ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P508'), ('name', 'BNCF Thesaurus ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P5437'), ('name', 'EuroVoc ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P562'), ('name', 'central bank/issuer')]
# [('prop', 'http://www.wikidata.org/prop/direct/P580'), ('name', 'start time')]
# [('prop', 'http://www.wikidata.org/prop/direct/P6058'), ('name', 'Larousse ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P6404'), ('name', "Treccani's Dizionario di Storia ID")]
# [('prop', 'http://www.wikidata.org/prop/direct/P646'), ('name', 'Freebase ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P6573'), ('name', 'Klexikon article ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P7007'), ('name', 'Wolfram Language unit code')]
# [('prop', 'http://www.wikidata.org/prop/direct/P7033'), ('name', 'Australian Educational Vocabulary ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P7749'), ('name', 'Nomenclature for Museum Cataloging')]
# [('prop', 'http://www.wikidata.org/prop/direct/P7818'), ('name', 'French Vikidia ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P7822'), ('name', 'Italian Vikidia ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P7827'), ('name', 'Spanish Vikidia ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P7829'), ('name', 'English Vikidia ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P7982'), ('name', 'Hrvatska enciklopedija ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P7996'), ('name', 'EH.Net Encyclopedia of Economic and Business History ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P8769'), ('name', 'Ontology of units of Measure 2.0 unit ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P902'), ('name', 'HDS ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P910'), ('name', "topic's main category")]
# [('prop', 'http://www.wikidata.org/prop/direct/P9318'), ('name', 'Ávvir topic ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P935'), ('name', 'Commons gallery')]
# [('prop', 'http://www.wikidata.org/prop/direct/P9545'), ('name', 'Encyclopedia of China Online Database ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P998'), ('name', 'Curlie ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P9059'), ('name', 'subdivision of this unit')]
# 66

# %%
# use country
queryString = """
SELECT DISTINCT ?obj ?name
WHERE { 
    wd:Q4916 wdt:P17 ?obj.
    # ?obj sc:name ?name.
}
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('obj', 'http://www.wikidata.org/entity/Q142'), ('name', 'France')]
# [('obj', 'http://www.wikidata.org/entity/Q183'), ('name', 'Germany')]
# [('obj', 'http://www.wikidata.org/entity/Q191'), ('name', 'Estonia')]
# [('obj', 'http://www.wikidata.org/entity/Q211'), ('name', 'Latvia')]
# [('obj', 'http://www.wikidata.org/entity/Q214'), ('name', 'Slovakia')]
# [('obj', 'http://www.wikidata.org/entity/Q215'), ('name', 'Slovenia')]
# [('obj', 'http://www.wikidata.org/entity/Q228'), ('name', 'Andorra')]
# [('obj', 'http://www.wikidata.org/entity/Q229'), ('name', 'Cyprus')]
# [('obj', 'http://www.wikidata.org/entity/Q233'), ('name', 'Malta')]
# [('obj', 'http://www.wikidata.org/entity/Q235'), ('name', 'Monaco')]
# [('obj', 'http://www.wikidata.org/entity/Q237'), ('name', 'Vatican City')]
# [('obj', 'http://www.wikidata.org/entity/Q238'), ('name', 'San Marino')]
# [('obj', 'http://www.wikidata.org/entity/Q27'), ('name', 'Ireland')]
# [('obj', 'http://www.wikidata.org/entity/Q29'), ('name', 'Spain')]
# [('obj', 'http://www.wikidata.org/entity/Q31'), ('name', 'Belgium')]
# [('obj', 'http://www.wikidata.org/entity/Q32'), ('name', 'Luxembourg')]
# [('obj', 'http://www.wikidata.org/entity/Q33'), ('name', 'Finland')]
# [('obj', 'http://www.wikidata.org/entity/Q37'), ('name', 'Lithuania')]
# [('obj', 'http://www.wikidata.org/entity/Q38'), ('name', 'Italy')]
# [('obj', 'http://www.wikidata.org/entity/Q40'), ('name', 'Austria')]
# [('obj', 'http://www.wikidata.org/entity/Q41'), ('name', 'Greece')]
# [('obj', 'http://www.wikidata.org/entity/Q45'), ('name', 'Portugal')]
# [('obj', 'http://www.wikidata.org/entity/Q55'), ('name', 'Netherlands')]
# 23

# %%
obj = [{"uri":r[0][1],"name":r[1][1]} for r in x]
evaluation.add_result(evaluation.get_index_workflow(pt),"2", evaluation.TYPE_SET ,"uri", obj)
# Out:
# The index of this workflow is: 1_1
# The path is /locale/data/jupyter/prando/notebook/2022/results/workflow1_1.json
# JSON object updated

# %% [markdown]
# ## Task 3

# %%
# use the property has part to object of euro-country-obj
queryString = """
SELECT DISTINCT ?x ?name
WHERE { 
    wd:Q4916 wdt:P17 ?obj.
    # ?obj wdt:P361 ?x.
    # ?x sc:name ?name.
}
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('x', 'http://www.wikidata.org/entity/Q1065'), ('name', 'United Nations')]
# [('x', 'http://www.wikidata.org/entity/Q13116'), ('name', 'Benelux')]
# [('x', 'http://www.wikidata.org/entity/Q215669'), ('name', 'Allies of the First World War')]
# [('x', 'http://www.wikidata.org/entity/Q27293'), ('name', 'Western Asia')]
# [('x', 'http://www.wikidata.org/entity/Q27468'), ('name', 'Eastern Europe')]
# [('x', 'http://www.wikidata.org/entity/Q27496'), ('name', 'Western Europe')]
# [('x', 'http://www.wikidata.org/entity/Q27509'), ('name', 'Central Europe')]
# [('x', 'http://www.wikidata.org/entity/Q29999'), ('name', 'Kingdom of the Netherlands')]
# [('x', 'http://www.wikidata.org/entity/Q39731'), ('name', 'Baltic states')]
# [('x', 'http://www.wikidata.org/entity/Q458'), ('name', 'European Union')]
# [('x', 'http://www.wikidata.org/entity/Q46'), ('name', 'Europe')]
# [('x', 'http://www.wikidata.org/entity/Q476033'), ('name', 'Low Countries')]
# [('x', 'http://www.wikidata.org/entity/Q50807777'), ('name', 'Southwestern Europe')]
# [('x', 'http://www.wikidata.org/entity/Q7204'), ('name', 'Middle East')]
# [('x', 'http://www.wikidata.org/entity/Q234963'), ('name', 'Catalan Countries')]
# [('x', 'http://www.wikidata.org/entity/Q27479'), ('name', 'Northern Europe')]
# [('x', 'http://www.wikidata.org/entity/Q52062'), ('name', 'Nordic countries')]
# [('x', 'http://www.wikidata.org/entity/Q263686'), ('name', 'Southeast Europe')]
# [('x', 'http://www.wikidata.org/entity/Q604496'), ('name', 'Fennoscandia')]
# [('x', 'http://www.wikidata.org/entity/Q1849394'), ('name', 'Pyrenees–Mediterranean Euroregion')]
# 20

# %%
# property of European Union
queryString = """
SELECT DISTINCT ?prop ?name
WHERE { 
    wd:Q458 ?prop ?x.
    #FILTER(?curr != wd:Q4916).
    #FILTER NOT EXISTS{wd:Q4916 wdt:P17 ?obj.}
    # ?prop sc:name ?name.
}
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('prop', 'http://www.wikidata.org/prop/direct/P1005'), ('name', 'Portuguese National Library ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P1051'), ('name', 'PSH ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P1081'), ('name', 'Human Development Index')]
# [('prop', 'http://www.wikidata.org/prop/direct/P1082'), ('name', 'population')]
# [('prop', 'http://www.wikidata.org/prop/direct/P112'), ('name', 'founded by')]
# [('prop', 'http://www.wikidata.org/prop/direct/P1125'), ('name', 'Gini coefficient')]
# [('prop', 'http://www.wikidata.org/prop/direct/P1151'), ('name', "topic's main Wikimedia portal")]
# [('prop', 'http://www.wikidata.org/prop/direct/P1245'), ('name', 'OmegaWiki Defined Meaning')]
# [('prop', 'http://www.wikidata.org/prop/direct/P1273'), ('name', 'CANTIC ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P1280'), ('name', 'CONOR.SI ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P1296'), ('name', 'Gran Enciclopèdia Catalana ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P1313'), ('name', 'office held by head of government')]
# [('prop', 'http://www.wikidata.org/prop/direct/P1315'), ('name', 'NLA Trove ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P1325'), ('name', 'external data available at')]
# [('prop', 'http://www.wikidata.org/prop/direct/P1343'), ('name', 'described by source')]
# [('prop', 'http://www.wikidata.org/prop/direct/P1344'), ('name', 'participant in')]
# [('prop', 'http://www.wikidata.org/prop/direct/P1365'), ('name', 'replaces')]
# [('prop', 'http://www.wikidata.org/prop/direct/P1417'), ('name', 'Encyclopædia Britannica Online ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P1424'), ('name', "topic's main template")]
# [('prop', 'http://www.wikidata.org/prop/direct/P1448'), ('name', 'official name')]
# [('prop', 'http://www.wikidata.org/prop/direct/P1451'), ('name', 'motto text')]
# [('prop', 'http://www.wikidata.org/prop/direct/P1482'), ('name', 'Stack Exchange tag')]
# [('prop', 'http://www.wikidata.org/prop/direct/P150'), ('name', 'contains administrative territorial entity')]
# [('prop', 'http://www.wikidata.org/prop/direct/P1546'), ('name', 'motto')]
# [('prop', 'http://www.wikidata.org/prop/direct/P1549'), ('name', 'demonym')]
# [('prop', 'http://www.wikidata.org/prop/direct/P155'), ('name', 'follows')]
# [('prop', 'http://www.wikidata.org/prop/direct/P159'), ('name', 'headquarters location')]
# [('prop', 'http://www.wikidata.org/prop/direct/P1617'), ('name', 'BBC Things ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P1622'), ('name', 'driving side')]
# [('prop', 'http://www.wikidata.org/prop/direct/P163'), ('name', 'flag')]
# [('prop', 'http://www.wikidata.org/prop/direct/P166'), ('name', 'award received')]
# [('prop', 'http://www.wikidata.org/prop/direct/P1807'), ('name', 'Great Aragonese Encyclopedia ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P1813'), ('name', 'short name')]
# [('prop', 'http://www.wikidata.org/prop/direct/P1889'), ('name', 'different from')]
# [('prop', 'http://www.wikidata.org/prop/direct/P1938'), ('name', 'Project Gutenberg author ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P194'), ('name', 'legislative body')]
# [('prop', 'http://www.wikidata.org/prop/direct/P2046'), ('name', 'area')]
# [('prop', 'http://www.wikidata.org/prop/direct/P208'), ('name', 'executive body')]
# [('prop', 'http://www.wikidata.org/prop/direct/P209'), ('name', 'highest judicial authority')]
# [('prop', 'http://www.wikidata.org/prop/direct/P213'), ('name', 'ISNI')]
# [('prop', 'http://www.wikidata.org/prop/direct/P214'), ('name', 'VIAF ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P2184'), ('name', 'history of topic')]
# [('prop', 'http://www.wikidata.org/prop/direct/P227'), ('name', 'GND ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P242'), ('name', 'locator map image')]
# [('prop', 'http://www.wikidata.org/prop/direct/P2427'), ('name', 'GRID ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P244'), ('name', 'Library of Congress authority ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P2581'), ('name', 'BabelNet ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P2633'), ('name', 'geography of topic')]
# [('prop', 'http://www.wikidata.org/prop/direct/P268'), ('name', 'Bibliothèque nationale de France ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P269'), ('name', 'IdRef ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P279'), ('name', 'subclass of')]
# [('prop', 'http://www.wikidata.org/prop/direct/P2852'), ('name', 'emergency telephone number')]
# [('prop', 'http://www.wikidata.org/prop/direct/P2884'), ('name', 'mains voltage')]
# [('prop', 'http://www.wikidata.org/prop/direct/P2888'), ('name', 'exact match')]
# [('prop', 'http://www.wikidata.org/prop/direct/P2924'), ('name', 'Great Russian Encyclopedia Online ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P2959'), ('name', 'permanent duplicated item')]
# [('prop', 'http://www.wikidata.org/prop/direct/P30'), ('name', 'continent')]
# [('prop', 'http://www.wikidata.org/prop/direct/P31'), ('name', 'instance of')]
# [('prop', 'http://www.wikidata.org/prop/direct/P3106'), ('name', 'Guardian topic ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P3153'), ('name', 'Crossref funder ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P3188'), ('name', 'Nobel prize ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P3221'), ('name', 'New York Times topic ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P3222'), ('name', 'NE.se ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P3365'), ('name', 'Treccani ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P3417'), ('name', 'Quora topic ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P349'), ('name', 'National Diet Library ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P3509'), ('name', 'Dagens Nyheter topic ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P355'), ('name', 'subsidiary')]
# [('prop', 'http://www.wikidata.org/prop/direct/P3569'), ('name', 'Cultureel Woordenboek ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P36'), ('name', 'capital')]
# [('prop', 'http://www.wikidata.org/prop/direct/P3612'), ('name', 'Le Monde diplomatique subject ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P37'), ('name', 'official language')]
# [('prop', 'http://www.wikidata.org/prop/direct/P373'), ('name', 'Commons category')]
# [('prop', 'http://www.wikidata.org/prop/direct/P3762'), ('name', 'openMLOL author ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P38'), ('name', 'currency')]
# [('prop', 'http://www.wikidata.org/prop/direct/P3827'), ('name', 'JSTOR topic ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P3847'), ('name', 'Open Library subject ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P3916'), ('name', 'UNESCO Thesaurus ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P3987'), ('name', 'SHARE Catalogue author ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P402'), ('name', 'OpenStreetMap relation ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P409'), ('name', 'Libraries Australia ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P41'), ('name', 'flag image')]
# [('prop', 'http://www.wikidata.org/prop/direct/P421'), ('name', 'located in time zone')]
# [('prop', 'http://www.wikidata.org/prop/direct/P4223'), ('name', "Treccani's Enciclopedia Italiana ID")]
# [('prop', 'http://www.wikidata.org/prop/direct/P4293'), ('name', 'PM20 folder ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P4427'), ('name', 'GACS ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P452'), ('name', 'industry')]
# [('prop', 'http://www.wikidata.org/prop/direct/P4527'), ('name', 'UK Parliament thesaurus ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P457'), ('name', 'foundational text')]
# [('prop', 'http://www.wikidata.org/prop/direct/P4613'), ('name', 'Encyclopedia of Modern Ukraine ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P463'), ('name', 'member of')]
# [('prop', 'http://www.wikidata.org/prop/direct/P47'), ('name', 'shares border with')]
# [('prop', 'http://www.wikidata.org/prop/direct/P4725'), ('name', 'C-SPAN organization ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P486'), ('name', 'MeSH descriptor ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P487'), ('name', 'Unicode character')]
# [('prop', 'http://www.wikidata.org/prop/direct/P5008'), ('name', 'on focus list of Wikimedia project')]
# [('prop', 'http://www.wikidata.org/prop/direct/P5019'), ('name', 'Brockhaus Enzyklopädie online ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P5125'), ('name', 'Wikimedia outline')]
# [('prop', 'http://www.wikidata.org/prop/direct/P5167'), ('name', 'vehicles per thousand people')]
# [('prop', 'http://www.wikidata.org/prop/direct/P5198'), ('name', 'ASC Leiden Thesaurus ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P5266'), ('name', 'Finnish national bibliography corporate name ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P527'), ('name', 'has part')]
# [('prop', 'http://www.wikidata.org/prop/direct/P530'), ('name', 'diplomatic relation')]
# [('prop', 'http://www.wikidata.org/prop/direct/P571'), ('name', 'inception')]
# [('prop', 'http://www.wikidata.org/prop/direct/P5905'), ('name', 'Comic Vine ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P6058'), ('name', 'Larousse ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P6104'), ('name', 'maintained by WikiProject')]
# [('prop', 'http://www.wikidata.org/prop/direct/P6200'), ('name', 'BBC News topic ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P6328'), ('name', 'Politika topic ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P6366'), ('name', 'Microsoft Academic ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P6385'), ('name', 'Krugosvet article')]
# [('prop', 'http://www.wikidata.org/prop/direct/P6404'), ('name', "Treccani's Dizionario di Storia ID")]
# [('prop', 'http://www.wikidata.org/prop/direct/P646'), ('name', 'Freebase ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P648'), ('name', 'Open Library ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P6573'), ('name', 'Klexikon article ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P6782'), ('name', 'ROR ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P691'), ('name', 'NKCR AUT ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P7208'), ('name', 'Liber Liber author ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P78'), ('name', 'top-level Internet domain')]
# [('prop', 'http://www.wikidata.org/prop/direct/P7818'), ('name', 'French Vikidia ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P7822'), ('name', 'Italian Vikidia ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P7827'), ('name', 'Spanish Vikidia ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P7829'), ('name', 'English Vikidia ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P7859'), ('name', 'WorldCat Identities ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P7867'), ('name', 'category for maps')]
# [('prop', 'http://www.wikidata.org/prop/direct/P7870'), ('name', 'Analysis & Policy Observatory term ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P7982'), ('name', 'Hrvatska enciklopedija ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P8024'), ('name', 'Nobel Laureate API ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P8309'), ('name', 'Yle topic ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P832'), ('name', 'public holiday')]
# [('prop', 'http://www.wikidata.org/prop/direct/P8402'), ('name', 'open data portal')]
# [('prop', 'http://www.wikidata.org/prop/direct/P8408'), ('name', 'KBpedia ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P85'), ('name', 'anthem')]
# [('prop', 'http://www.wikidata.org/prop/direct/P856'), ('name', 'official website')]
# [('prop', 'http://www.wikidata.org/prop/direct/P8744'), ('name', 'economy of topic')]
# [('prop', 'http://www.wikidata.org/prop/direct/P8935'), ('name', 'Encyclopedia of the History of Ukraine ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P902'), ('name', 'HDS ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P9037'), ('name', 'BHCL UUID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P910'), ('name', "topic's main category")]
# [('prop', 'http://www.wikidata.org/prop/direct/P9100'), ('name', 'GitHub topic')]
# [('prop', 'http://www.wikidata.org/prop/direct/P9241'), ('name', 'demographics of topic')]
# [('prop', 'http://www.wikidata.org/prop/direct/P9272'), ('name', 'DeCS ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P9287'), ('name', 'Cyprus Bibliography ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P9349'), ('name', 'France24 topic ID (Arabic)')]
# [('prop', 'http://www.wikidata.org/prop/direct/P935'), ('name', 'Commons gallery')]
# [('prop', 'http://www.wikidata.org/prop/direct/P9368'), ('name', 'CNA topic ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P948'), ('name', 'page banner')]
# [('prop', 'http://www.wikidata.org/prop/direct/P9482'), ('name', 'Catalogue of the General State Archives ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P950'), ('name', 'Biblioteca Nacional de España ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P9545'), ('name', 'Encyclopedia of China Online Database ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P9629'), ('name', 'Armeniapedia ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P973'), ('name', 'described at URL')]
# [('prop', 'http://www.wikidata.org/prop/direct/P998'), ('name', 'Curlie ID')]
# 153

# %%
# looking for the part of the EU
queryString = """
SELECT DISTINCT ?x ?name
WHERE { 
    wd:Q458 wdt:P527 ?x.
    # ?x sc:name ?name.
}
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('x', 'http://www.wikidata.org/entity/Q142'), ('name', 'France')]
# [('x', 'http://www.wikidata.org/entity/Q183'), ('name', 'Germany')]
# [('x', 'http://www.wikidata.org/entity/Q191'), ('name', 'Estonia')]
# [('x', 'http://www.wikidata.org/entity/Q211'), ('name', 'Latvia')]
# [('x', 'http://www.wikidata.org/entity/Q213'), ('name', 'Czech Republic')]
# [('x', 'http://www.wikidata.org/entity/Q214'), ('name', 'Slovakia')]
# [('x', 'http://www.wikidata.org/entity/Q215'), ('name', 'Slovenia')]
# [('x', 'http://www.wikidata.org/entity/Q218'), ('name', 'Romania')]
# [('x', 'http://www.wikidata.org/entity/Q219'), ('name', 'Bulgaria')]
# [('x', 'http://www.wikidata.org/entity/Q224'), ('name', 'Croatia')]
# [('x', 'http://www.wikidata.org/entity/Q229'), ('name', 'Cyprus')]
# [('x', 'http://www.wikidata.org/entity/Q233'), ('name', 'Malta')]
# [('x', 'http://www.wikidata.org/entity/Q28'), ('name', 'Hungary')]
# [('x', 'http://www.wikidata.org/entity/Q29'), ('name', 'Spain')]
# [('x', 'http://www.wikidata.org/entity/Q31'), ('name', 'Belgium')]
# [('x', 'http://www.wikidata.org/entity/Q32'), ('name', 'Luxembourg')]
# [('x', 'http://www.wikidata.org/entity/Q33'), ('name', 'Finland')]
# [('x', 'http://www.wikidata.org/entity/Q34'), ('name', 'Sweden')]
# [('x', 'http://www.wikidata.org/entity/Q35'), ('name', 'Denmark')]
# [('x', 'http://www.wikidata.org/entity/Q36'), ('name', 'Poland')]
# [('x', 'http://www.wikidata.org/entity/Q37'), ('name', 'Lithuania')]
# [('x', 'http://www.wikidata.org/entity/Q38'), ('name', 'Italy')]
# [('x', 'http://www.wikidata.org/entity/Q40'), ('name', 'Austria')]
# [('x', 'http://www.wikidata.org/entity/Q41'), ('name', 'Greece')]
# [('x', 'http://www.wikidata.org/entity/Q45'), ('name', 'Portugal')]
# [('x', 'http://www.wikidata.org/entity/Q55'), ('name', 'Netherlands')]
# [('x', 'http://www.wikidata.org/entity/Q22890'), ('name', 'Ireland')]
# 27

# %%
# find countries which belong to EU but they don't uses Euro as currency
queryString = """
SELECT DISTINCT ?x ?name ?curr ?cName
WHERE { 
    wd:Q458 wdt:P527 ?x.
    # ?x wdt:P38 ?curr.
    FILTER(?curr != wd:Q4916).
    # ?x sc:name ?name.
    # ?curr sc:name ?cName.
}
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('x', 'http://www.wikidata.org/entity/Q213'), ('name', 'Czech Republic'), ('curr', 'http://www.wikidata.org/entity/Q131016'), ('cName', 'Czech koruna')]
# [('x', 'http://www.wikidata.org/entity/Q218'), ('name', 'Romania'), ('curr', 'http://www.wikidata.org/entity/Q131645'), ('cName', 'Romanian leu')]
# [('x', 'http://www.wikidata.org/entity/Q219'), ('name', 'Bulgaria'), ('curr', 'http://www.wikidata.org/entity/Q172540'), ('cName', 'Bulgarian lev')]
# [('x', 'http://www.wikidata.org/entity/Q224'), ('name', 'Croatia'), ('curr', 'http://www.wikidata.org/entity/Q26360'), ('cName', 'Croatian kuna')]
# [('x', 'http://www.wikidata.org/entity/Q28'), ('name', 'Hungary'), ('curr', 'http://www.wikidata.org/entity/Q47190'), ('cName', 'forint')]
# [('x', 'http://www.wikidata.org/entity/Q34'), ('name', 'Sweden'), ('curr', 'http://www.wikidata.org/entity/Q122922'), ('cName', 'Swedish krona')]
# [('x', 'http://www.wikidata.org/entity/Q35'), ('name', 'Denmark'), ('curr', 'http://www.wikidata.org/entity/Q25417'), ('cName', 'Danish krone')]
# [('x', 'http://www.wikidata.org/entity/Q36'), ('name', 'Poland'), ('curr', 'http://www.wikidata.org/entity/Q123213'), ('cName', 'złoty')]
# 8

# %%
# URI associated to another URI
objs = []
for i in x:
    f_uri = i[0][1]
    f_name = i[1][1]
    c_uri = i[2][1]
    c_name = i[3][1]
    obj = {}
    obj["refers_to"] = f_uri
    obj["refers_to_name"] = f_name
    obj["check"] = ["uri","name"]
    obj["uri"]= c_uri
    obj["name"]= c_name
    objs.append(obj)

evaluation.add_result(evaluation.get_index_workflow(pt),"3", evaluation.TYPE_REFERRED ,["uri","name"], objs)
# Out:
# The index of this workflow is: 1_1
# The path is /locale/data/jupyter/prando/notebook/2022/results/workflow1_1.json
# JSON object updated

# %% [markdown]
# ## Task 4

# %%
# from one of the first query use P1365 replaces
queryString = """
SELECT DISTINCT ?x ?name
WHERE { 
    wd:Q4916 wdt:P1365 ?x.
    # ?x sc:name ?name.
}
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('x', 'http://www.wikidata.org/entity/Q270642'), ('name', 'Irish pound')]
# [('x', 'http://www.wikidata.org/entity/Q788472'), ('name', 'Dutch guilder')]
# [('x', 'http://www.wikidata.org/entity/Q1546443'), ('name', 'Greek drachma')]
# [('x', 'http://www.wikidata.org/entity/Q203354'), ('name', 'Finnish markka')]
# [('x', 'http://www.wikidata.org/entity/Q204992'), ('name', 'Italian lira')]
# [('x', 'http://www.wikidata.org/entity/Q468474'), ('name', 'Portuguese escudo')]
# [('x', 'http://www.wikidata.org/entity/Q184172'), ('name', 'French franc')]
# [('x', 'http://www.wikidata.org/entity/Q189097'), ('name', 'peseta')]
# [('x', 'http://www.wikidata.org/entity/Q16068'), ('name', 'Deutsche Mark')]
# [('x', 'http://www.wikidata.org/entity/Q174467'), ('name', 'Maltese lira')]
# [('x', 'http://www.wikidata.org/entity/Q133011'), ('name', 'Latvian lats')]
# [('x', 'http://www.wikidata.org/entity/Q183354'), ('name', 'Vatican lira')]
# [('x', 'http://www.wikidata.org/entity/Q129983'), ('name', 'Estonian kroon')]
# [('x', 'http://www.wikidata.org/entity/Q25627'), ('name', 'Lithuanian litas')]
# [('x', 'http://www.wikidata.org/entity/Q193716'), ('name', 'Cypriot pound')]
# [('x', 'http://www.wikidata.org/entity/Q221828'), ('name', 'European Currency Unit')]
# [('x', 'http://www.wikidata.org/entity/Q213940'), ('name', 'Luxembourg franc')]
# [('x', 'http://www.wikidata.org/entity/Q178874'), ('name', 'Slovak koruna')]
# [('x', 'http://www.wikidata.org/entity/Q208730'), ('name', 'Austrian schilling')]
# [('x', 'http://www.wikidata.org/entity/Q232415'), ('name', 'Belgian franc')]
# [('x', 'http://www.wikidata.org/entity/Q1047040'), ('name', 'Monegasque franc')]
# [('x', 'http://www.wikidata.org/entity/Q1063029'), ('name', 'Sammarinese lira')]
# [('x', 'http://www.wikidata.org/entity/Q208133'), ('name', 'Slovenian tolar')]
# 23

# %%
# from one of the first query use P1365 replaces
queryString = """
SELECT DISTINCT ?country ?cName ?x ?name 
WHERE { 
    wd:Q4916 wdt:P1365 ?x.
    # ?country wdt:P38 wd:Q4916.
    # ?x wdt:P17 ?country.
    # ?x sc:name ?name.
    # ?country sc:name ?cName.
}
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('country', 'http://www.wikidata.org/entity/Q27'), ('cName', 'Ireland'), ('x', 'http://www.wikidata.org/entity/Q270642'), ('name', 'Irish pound')]
# [('country', 'http://www.wikidata.org/entity/Q29999'), ('cName', 'Kingdom of the Netherlands'), ('x', 'http://www.wikidata.org/entity/Q788472'), ('name', 'Dutch guilder')]
# [('country', 'http://www.wikidata.org/entity/Q41'), ('cName', 'Greece'), ('x', 'http://www.wikidata.org/entity/Q1546443'), ('name', 'Greek drachma')]
# [('country', 'http://www.wikidata.org/entity/Q33'), ('cName', 'Finland'), ('x', 'http://www.wikidata.org/entity/Q203354'), ('name', 'Finnish markka')]
# [('country', 'http://www.wikidata.org/entity/Q38'), ('cName', 'Italy'), ('x', 'http://www.wikidata.org/entity/Q204992'), ('name', 'Italian lira')]
# [('country', 'http://www.wikidata.org/entity/Q45'), ('cName', 'Portugal'), ('x', 'http://www.wikidata.org/entity/Q468474'), ('name', 'Portuguese escudo')]
# [('country', 'http://www.wikidata.org/entity/Q235'), ('cName', 'Monaco'), ('x', 'http://www.wikidata.org/entity/Q184172'), ('name', 'French franc')]
# [('country', 'http://www.wikidata.org/entity/Q142'), ('cName', 'France'), ('x', 'http://www.wikidata.org/entity/Q184172'), ('name', 'French franc')]
# [('country', 'http://www.wikidata.org/entity/Q228'), ('cName', 'Andorra'), ('x', 'http://www.wikidata.org/entity/Q184172'), ('name', 'French franc')]
# [('country', 'http://www.wikidata.org/entity/Q228'), ('cName', 'Andorra'), ('x', 'http://www.wikidata.org/entity/Q189097'), ('name', 'peseta')]
# [('country', 'http://www.wikidata.org/entity/Q29'), ('cName', 'Spain'), ('x', 'http://www.wikidata.org/entity/Q189097'), ('name', 'peseta')]
# [('country', 'http://www.wikidata.org/entity/Q183'), ('cName', 'Germany'), ('x', 'http://www.wikidata.org/entity/Q16068'), ('name', 'Deutsche Mark')]
# [('country', 'http://www.wikidata.org/entity/Q233'), ('cName', 'Malta'), ('x', 'http://www.wikidata.org/entity/Q174467'), ('name', 'Maltese lira')]
# [('country', 'http://www.wikidata.org/entity/Q211'), ('cName', 'Latvia'), ('x', 'http://www.wikidata.org/entity/Q133011'), ('name', 'Latvian lats')]
# [('country', 'http://www.wikidata.org/entity/Q237'), ('cName', 'Vatican City'), ('x', 'http://www.wikidata.org/entity/Q183354'), ('name', 'Vatican lira')]
# [('country', 'http://www.wikidata.org/entity/Q191'), ('cName', 'Estonia'), ('x', 'http://www.wikidata.org/entity/Q129983'), ('name', 'Estonian kroon')]
# [('country', 'http://www.wikidata.org/entity/Q37'), ('cName', 'Lithuania'), ('x', 'http://www.wikidata.org/entity/Q25627'), ('name', 'Lithuanian litas')]
# [('country', 'http://www.wikidata.org/entity/Q229'), ('cName', 'Cyprus'), ('x', 'http://www.wikidata.org/entity/Q193716'), ('name', 'Cypriot pound')]
# [('country', 'http://www.wikidata.org/entity/Q32'), ('cName', 'Luxembourg'), ('x', 'http://www.wikidata.org/entity/Q213940'), ('name', 'Luxembourg franc')]
# [('country', 'http://www.wikidata.org/entity/Q214'), ('cName', 'Slovakia'), ('x', 'http://www.wikidata.org/entity/Q178874'), ('name', 'Slovak koruna')]
# [('country', 'http://www.wikidata.org/entity/Q40'), ('cName', 'Austria'), ('x', 'http://www.wikidata.org/entity/Q208730'), ('name', 'Austrian schilling')]
# [('country', 'http://www.wikidata.org/entity/Q31'), ('cName', 'Belgium'), ('x', 'http://www.wikidata.org/entity/Q232415'), ('name', 'Belgian franc')]
# [('country', 'http://www.wikidata.org/entity/Q235'), ('cName', 'Monaco'), ('x', 'http://www.wikidata.org/entity/Q1047040'), ('name', 'Monegasque franc')]
# [('country', 'http://www.wikidata.org/entity/Q238'), ('cName', 'San Marino'), ('x', 'http://www.wikidata.org/entity/Q1063029'), ('name', 'Sammarinese lira')]
# [('country', 'http://www.wikidata.org/entity/Q215'), ('cName', 'Slovenia'), ('x', 'http://www.wikidata.org/entity/Q208133'), ('name', 'Slovenian tolar')]
# 25

# %%
# URI associated to another URI
objs = []
for i in x:
    f_uri = i[0][1]
    f_name = i[1][1]
    c_uri = i[2][1]
    c_name = i[3][1]
    obj = {}
    obj["refers_to"] = f_uri
    obj["refers_to_name"] = f_name
    obj["check"] = ["uri","name"]
    obj["uri"]= c_uri
    obj["name"]= c_name
    objs.append(obj)

evaluation.add_result(evaluation.get_index_workflow(pt),"4", evaluation.TYPE_REFERRED ,["uri","name"], objs)
# Out:
# The index of this workflow is: 1_1
# The path is /locale/data/jupyter/prando/notebook/2022/results/workflow1_1.json
# JSON object updated

# %% [markdown]
# ## Task 5

# %%
# find dollars
queryString = """
SELECT DISTINCT ?x ?name 
WHERE { 
    # ?x wdt:P31 wd:Q8142.
    #?country wdt:P38 ?x.
    # ?x sc:name ?name.
    FILTER(REGEX(?name,"dollar")).
}
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('x', 'http://www.wikidata.org/entity/Q242890'), ('name', 'Trinidad and Tobago dollar')]
# [('x', 'http://www.wikidata.org/entity/Q942092'), ('name', 'British West Indies dollar')]
# [('x', 'http://www.wikidata.org/entity/Q1104069'), ('name', 'Canadian dollar')]
# [('x', 'http://www.wikidata.org/entity/Q259502'), ('name', 'Australian dollar')]
# [('x', 'http://www.wikidata.org/entity/Q4597'), ('name', 'Solomon Islands dollar')]
# [('x', 'http://www.wikidata.org/entity/Q4917'), ('name', 'United States dollar')]
# [('x', 'http://www.wikidata.org/entity/Q2411666'), ('name', 'Newfoundland dollar')]
# [('x', 'http://www.wikidata.org/entity/Q209792'), ('name', 'Jamaican dollar')]
# [('x', 'http://www.wikidata.org/entity/Q15039722'), ('name', 'spanish dollar')]
# [('x', 'http://www.wikidata.org/entity/Q31015'), ('name', 'Hong Kong dollar')]
# [('x', 'http://www.wikidata.org/entity/Q261447'), ('name', 'Straits dollar')]
# [('x', 'http://www.wikidata.org/entity/Q4592'), ('name', 'Fijian dollar')]
# [('x', 'http://www.wikidata.org/entity/Q26365'), ('name', 'Eastern Caribbean dollar')]
# [('x', 'http://www.wikidata.org/entity/Q1323382'), ('name', 'New Brunswick dollar')]
# [('x', 'http://www.wikidata.org/entity/Q2407759'), ('name', 'Malaya and British Borneo dollar')]
# [('x', 'http://www.wikidata.org/entity/Q2414453'), ('name', 'Sarawak dollar')]
# [('x', 'http://www.wikidata.org/entity/Q242988'), ('name', 'Liberian dollar')]
# [('x', 'http://www.wikidata.org/entity/Q1472704'), ('name', 'New Zealand dollar')]
# [('x', 'http://www.wikidata.org/entity/Q3712663'), ('name', 'Antigua dollar')]
# [('x', 'http://www.wikidata.org/entity/Q3712665'), ('name', 'Nevisian dollar')]
# [('x', 'http://www.wikidata.org/entity/Q194351'), ('name', 'Barbadian dollar')]
# [('x', 'http://www.wikidata.org/entity/Q1934986'), ('name', 'Nova Scotian dollar')]
# [('x', 'http://www.wikidata.org/entity/Q2344772'), ('name', 'Malayan dollar')]
# [('x', 'http://www.wikidata.org/entity/Q1049963'), ('name', 'Kiribati dollar')]
# [('x', 'http://www.wikidata.org/entity/Q275112'), ('name', 'Belize dollar')]
# [('x', 'http://www.wikidata.org/entity/Q4406'), ('name', 'Tuvaluan dollar')]
# [('x', 'http://www.wikidata.org/entity/Q210478'), ('name', 'Bermudian dollar')]
# [('x', 'http://www.wikidata.org/entity/Q213005'), ('name', 'Guyanese dollar')]
# [('x', 'http://www.wikidata.org/entity/Q16080864'), ('name', 'Province of Canada dollar')]
# [('x', 'http://www.wikidata.org/entity/Q686163'), ('name', 'Confederate States dollar')]
# [('x', 'http://www.wikidata.org/entity/Q718954'), ('name', 'Old Taiwan dollar')]
# [('x', 'http://www.wikidata.org/entity/Q202036'), ('name', 'Surinamese dollar')]
# [('x', 'http://www.wikidata.org/entity/Q202462'), ('name', 'Namibian dollar')]
# [('x', 'http://www.wikidata.org/entity/Q3712664'), ('name', 'Grenadan dollar')]
# [('x', 'http://www.wikidata.org/entity/Q3712666'), ('name', 'Saint Kitts dollar')]
# [('x', 'http://www.wikidata.org/entity/Q3712669'), ('name', 'Saint Lucia dollar')]
# [('x', 'http://www.wikidata.org/entity/Q206319'), ('name', 'Brunei dollar')]
# [('x', 'http://www.wikidata.org/entity/Q2296365'), ('name', 'British North Borneo dollar')]
# [('x', 'http://www.wikidata.org/entity/Q726666'), ('name', 'Mongolian dollar')]
# [('x', 'http://www.wikidata.org/entity/Q3712661'), ('name', 'Prince Edward Island dollar')]
# [('x', 'http://www.wikidata.org/entity/Q208526'), ('name', 'New Taiwan dollar')]
# [('x', 'http://www.wikidata.org/entity/Q2328868'), ('name', 'Hawaiian dollar')]
# [('x', 'http://www.wikidata.org/entity/Q190951'), ('name', 'Singapore dollar')]
# [('x', 'http://www.wikidata.org/entity/Q4165057'), ('name', 'Niue dollar')]
# [('x', 'http://www.wikidata.org/entity/Q4165058'), ('name', 'Pitcairn Islands dollar')]
# [('x', 'http://www.wikidata.org/entity/Q507737'), ('name', 'Cook Islands dollar')]
# [('x', 'http://www.wikidata.org/entity/Q3712668'), ('name', 'Saint Vincent dollar')]
# [('x', 'http://www.wikidata.org/entity/Q319885'), ('name', 'Cayman Islands dollar')]
# [('x', 'http://www.wikidata.org/entity/Q194339'), ('name', 'Bahamian dollar')]
# [('x', 'http://www.wikidata.org/entity/Q1607372'), ('name', 'Kiautschou dollar')]
# [('x', 'http://www.wikidata.org/entity/Q3712671'), ('name', 'Tobagan dollar')]
# [('x', 'http://www.wikidata.org/entity/Q1647239'), ('name', 'Sumatran dollar')]
# [('x', 'http://www.wikidata.org/entity/Q3712660'), ('name', 'British Columbia dollar')]
# [('x', 'http://www.wikidata.org/entity/Q3712672'), ('name', 'Trinidadian dollar')]
# 54

# %%
# find some dollar classes
queryString = """
SELECT DISTINCT ?y ?n 
WHERE { 
    # ?x wdt:P31 wd:Q8142.
    # ?x wdt:P31 ?y.
    # ?x sc:name ?name.
    FILTER(REGEX(?name,"dollar")).
    # ?y sc:name ?n.
}
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('y', 'http://www.wikidata.org/entity/Q14083'), ('n', 'dollar')]
# [('y', 'http://www.wikidata.org/entity/Q8142'), ('n', 'currency')]
# [('y', 'http://www.wikidata.org/entity/Q28795800'), ('n', 'decimal currency')]
# [('y', 'http://www.wikidata.org/entity/Q25530138'), ('n', 'yuan')]
# [('y', 'http://www.wikidata.org/entity/Q1643989'), ('n', 'legal tender')]
# [('y', 'http://www.wikidata.org/entity/Q756202'), ('n', 'reserve currency')]
# 6

# %%
# list instances of dollar
queryString = """
SELECT DISTINCT ?x ?name 
WHERE { 
    # ?x wdt:P31 wd:Q14083.
    # ?x sc:name ?name.
}
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('x', 'http://www.wikidata.org/entity/Q242890'), ('name', 'Trinidad and Tobago dollar')]
# [('x', 'http://www.wikidata.org/entity/Q942092'), ('name', 'British West Indies dollar')]
# [('x', 'http://www.wikidata.org/entity/Q1104069'), ('name', 'Canadian dollar')]
# [('x', 'http://www.wikidata.org/entity/Q259502'), ('name', 'Australian dollar')]
# [('x', 'http://www.wikidata.org/entity/Q4597'), ('name', 'Solomon Islands dollar')]
# [('x', 'http://www.wikidata.org/entity/Q4917'), ('name', 'United States dollar')]
# [('x', 'http://www.wikidata.org/entity/Q2411666'), ('name', 'Newfoundland dollar')]
# [('x', 'http://www.wikidata.org/entity/Q209792'), ('name', 'Jamaican dollar')]
# [('x', 'http://www.wikidata.org/entity/Q392858'), ('name', 'Rhodesian dollar')]
# [('x', 'http://www.wikidata.org/entity/Q31015'), ('name', 'Hong Kong dollar')]
# [('x', 'http://www.wikidata.org/entity/Q4592'), ('name', 'Fijian dollar')]
# [('x', 'http://www.wikidata.org/entity/Q4817670'), ('name', 'Coins and postage stamps of Sealand')]
# [('x', 'http://www.wikidata.org/entity/Q26365'), ('name', 'Eastern Caribbean dollar')]
# [('x', 'http://www.wikidata.org/entity/Q1323382'), ('name', 'New Brunswick dollar')]
# [('x', 'http://www.wikidata.org/entity/Q242988'), ('name', 'Liberian dollar')]
# [('x', 'http://www.wikidata.org/entity/Q19831166'), ('name', 'Conch Dollar')]
# [('x', 'http://www.wikidata.org/entity/Q1472704'), ('name', 'New Zealand dollar')]
# [('x', 'http://www.wikidata.org/entity/Q194351'), ('name', 'Barbadian dollar')]
# [('x', 'http://www.wikidata.org/entity/Q1934986'), ('name', 'Nova Scotian dollar')]
# [('x', 'http://www.wikidata.org/entity/Q2344772'), ('name', 'Malayan dollar')]
# [('x', 'http://www.wikidata.org/entity/Q1049963'), ('name', 'Kiribati dollar')]
# [('x', 'http://www.wikidata.org/entity/Q275112'), ('name', 'Belize dollar')]
# [('x', 'http://www.wikidata.org/entity/Q4406'), ('name', 'Tuvaluan dollar')]
# [('x', 'http://www.wikidata.org/entity/Q210478'), ('name', 'Bermudian dollar')]
# [('x', 'http://www.wikidata.org/entity/Q182803'), ('name', 'Zimbabwean dollar')]
# [('x', 'http://www.wikidata.org/entity/Q213005'), ('name', 'Guyanese dollar')]
# [('x', 'http://www.wikidata.org/entity/Q16080864'), ('name', 'Province of Canada dollar')]
# [('x', 'http://www.wikidata.org/entity/Q686163'), ('name', 'Confederate States dollar')]
# [('x', 'http://www.wikidata.org/entity/Q718954'), ('name', 'Old Taiwan dollar')]
# [('x', 'http://www.wikidata.org/entity/Q202036'), ('name', 'Surinamese dollar')]
# [('x', 'http://www.wikidata.org/entity/Q202462'), ('name', 'Namibian dollar')]
# [('x', 'http://www.wikidata.org/entity/Q206319'), ('name', 'Brunei dollar')]
# [('x', 'http://www.wikidata.org/entity/Q3712661'), ('name', 'Prince Edward Island dollar')]
# [('x', 'http://www.wikidata.org/entity/Q208526'), ('name', 'New Taiwan dollar')]
# [('x', 'http://www.wikidata.org/entity/Q2328868'), ('name', 'Hawaiian dollar')]
# [('x', 'http://www.wikidata.org/entity/Q190951'), ('name', 'Singapore dollar')]
# [('x', 'http://www.wikidata.org/entity/Q507737'), ('name', 'Cook Islands dollar')]
# [('x', 'http://www.wikidata.org/entity/Q319885'), ('name', 'Cayman Islands dollar')]
# [('x', 'http://www.wikidata.org/entity/Q194339'), ('name', 'Bahamian dollar')]
# [('x', 'http://www.wikidata.org/entity/Q1607372'), ('name', 'Kiautschou dollar')]
# [('x', 'http://www.wikidata.org/entity/Q65067684'), ('name', 'RTGS Dollar')]
# 41

# %%
obj = [{"uri":r[0][1],"name":r[1][1]} for r in x]
evaluation.add_result(evaluation.get_index_workflow(pt),"5", evaluation.TYPE_SET ,"uri", obj)
# Out:
# The index of this workflow is: 1_1
# The path is /locale/data/jupyter/prando/notebook/2022/results/workflow1_1.json
# JSON object updated

# %% [markdown]
# ## Task 6

# %%
# find currencies used in more than one countries
queryString = """
SELECT DISTINCT ?x ?name (COUNT(DISTINCT ?country) AS ?count)
WHERE { 
    # ?x wdt:P31 wd:Q8142.
    # ?country wdt:P38 ?x;
        wdt:P31/wdt:P279* wd:Q6256.
    # ?x sc:name ?name.
}
GROUP BY ?x ?name
HAVING (COUNT(DISTINCT ?country)>1)
ORDER BY DESC (?count)
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('x', 'http://www.wikidata.org/entity/Q4916'), ('name', 'euro'), ('count', '25')]
# [('x', 'http://www.wikidata.org/entity/Q4917'), ('name', 'United States dollar'), ('count', '12')]
# [('x', 'http://www.wikidata.org/entity/Q861690'), ('name', 'West African CFA franc'), ('count', '8')]
# [('x', 'http://www.wikidata.org/entity/Q26365'), ('name', 'Eastern Caribbean dollar'), ('count', '6')]
# [('x', 'http://www.wikidata.org/entity/Q847739'), ('name', 'Central African CFA franc'), ('count', '6')]
# [('x', 'http://www.wikidata.org/entity/Q199462'), ('name', 'Egyptian pound'), ('count', '4')]
# [('x', 'http://www.wikidata.org/entity/Q259502'), ('name', 'Australian dollar'), ('count', '4')]
# [('x', 'http://www.wikidata.org/entity/Q25224'), ('name', 'pound sterling'), ('count', '3')]
# [('x', 'http://www.wikidata.org/entity/Q181907'), ('name', 'South African rand'), ('count', '3')]
# [('x', 'http://www.wikidata.org/entity/Q25417'), ('name', 'Danish krone'), ('count', '3')]
# [('x', 'http://www.wikidata.org/entity/Q199471'), ('name', 'Afghan afghani'), ('count', '3')]
# [('x', 'http://www.wikidata.org/entity/Q1472704'), ('name', 'New Zealand dollar'), ('count', '3')]
# [('x', 'http://www.wikidata.org/entity/Q25344'), ('name', 'Swiss franc'), ('count', '2')]
# [('x', 'http://www.wikidata.org/entity/Q130498'), ('name', 'Armenian dram'), ('count', '2')]
# [('x', 'http://www.wikidata.org/entity/Q8146'), ('name', 'Japanese yen'), ('count', '2')]
# [('x', 'http://www.wikidata.org/entity/Q41044'), ('name', 'Russian ruble'), ('count', '2')]
# [('x', 'http://www.wikidata.org/entity/Q206243'), ('name', 'birr'), ('count', '2')]
# [('x', 'http://www.wikidata.org/entity/Q191830'), ('name', 'dinar'), ('count', '2')]
# [('x', 'http://www.wikidata.org/entity/Q172872'), ('name', 'Turkish lira'), ('count', '2')]
# [('x', 'http://www.wikidata.org/entity/Q184172'), ('name', 'French franc'), ('count', '2')]
# [('x', 'http://www.wikidata.org/entity/Q191068'), ('name', 'Faroese króna'), ('count', '2')]
# [('x', 'http://www.wikidata.org/entity/Q188608'), ('name', 'Iranian rial'), ('count', '2')]
# 22

# %% [markdown]
# ## Task 7

# %%
# from the first query I remember the property population P1082
queryString = """
SELECT DISTINCT ?x ?name (SUM(?maxP) AS ?count)
WHERE { 
    ## sub query
    {
        SELECT ?country MAX(?population) AS ?maxP WHERE{
            # ?country wdt:P38 ?x;
                wdt:P31/wdt:P279* wd:Q6256.
            OPTIONAL{?country wdt:P1082 ?population.}
        }
        GROUP BY ?country
    }
    # ?x wdt:P31 wd:Q8142.
    # ?country wdt:P38 ?x;
        wdt:P31/wdt:P279* wd:Q6256.
    OPTIONAL{
        # ?country wdt:P1082 ?population.
        FILTER(?population = ?maxP).
    }
    # ?x sc:name ?name.
}
GROUP BY ?x ?name
HAVING (COUNT(DISTINCT ?country)>1)
ORDER BY DESC (?count)
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('x', 'http://www.wikidata.org/entity/Q25224'), ('name', 'pound sterling'), ('count', '6106448730')]
# [('x', 'http://www.wikidata.org/entity/Q4916'), ('name', 'euro'), ('count', '1613516682')]
# [('x', 'http://www.wikidata.org/entity/Q4917'), ('name', 'United States dollar'), ('count', '1553254316')]
# [('x', 'http://www.wikidata.org/entity/Q8146'), ('name', 'Japanese yen'), ('count', '954147390')]
# [('x', 'http://www.wikidata.org/entity/Q199462'), ('name', 'Egyptian pound'), ('count', '947988270')]
# [('x', 'http://www.wikidata.org/entity/Q206243'), ('name', 'birr'), ('count', '629744628')]
# [('x', 'http://www.wikidata.org/entity/Q861690'), ('name', 'West African CFA franc'), ('count', '599518780')]
# [('x', 'http://www.wikidata.org/entity/Q199471'), ('name', 'Afghan afghani'), ('count', '358234802')]
# [('x', 'http://www.wikidata.org/entity/Q188608'), ('name', 'Iranian rial'), ('count', '319864920')]
# [('x', 'http://www.wikidata.org/entity/Q181907'), ('name', 'South African rand'), ('count', '262024610')]
# [('x', 'http://www.wikidata.org/entity/Q847739'), ('name', 'Central African CFA franc'), ('count', '240614272')]
# [('x', 'http://www.wikidata.org/entity/Q259502'), ('name', 'Australian dollar'), ('count', '147961876')]
# [('x', 'http://www.wikidata.org/entity/Q25417'), ('name', 'Danish krone'), ('count', '94084876')]
# [('x', 'http://www.wikidata.org/entity/Q1472704'), ('name', 'New Zealand dollar'), ('count', '40974584')]
# [('x', 'http://www.wikidata.org/entity/Q191068'), ('name', 'Faroese króna'), ('count', '35690230')]
# [('x', 'http://www.wikidata.org/entity/Q25344'), ('name', 'Swiss franc'), ('count', '34015756')]
# [('x', 'http://www.wikidata.org/entity/Q26365'), ('name', 'Eastern Caribbean dollar'), ('count', '4874934')]
# [('x', 'http://www.wikidata.org/entity/Q191830'), ('name', 'dinar')]
# 18

# %%
# from the first query I remember the property population P1082
queryString = """
SELECT DISTINCT ?x ?name (SUM(?population) AS ?count)
WHERE { 
    # ?x wdt:P31 wd:Q8142.
    # ?country wdt:P38 ?x;
        wdt:P31/wdt:P279* wd:Q6256;
        wdt:P1082 ?population.
    # ?x sc:name ?name.
}
GROUP BY ?x ?name
HAVING (COUNT(DISTINCT ?country)>1)
ORDER BY DESC (?count)
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('x', 'http://www.wikidata.org/entity/Q25224'), ('name', 'pound sterling'), ('count', '6106448730')]
# [('x', 'http://www.wikidata.org/entity/Q4916'), ('name', 'euro'), ('count', '1652751098')]
# [('x', 'http://www.wikidata.org/entity/Q4917'), ('name', 'United States dollar'), ('count', '1553365694')]
# [('x', 'http://www.wikidata.org/entity/Q199462'), ('name', 'Egyptian pound'), ('count', '973490270')]
# [('x', 'http://www.wikidata.org/entity/Q8146'), ('name', 'Japanese yen'), ('count', '954147390')]
# [('x', 'http://www.wikidata.org/entity/Q172872'), ('name', 'Turkish lira'), ('count', '836770872')]
# [('x', 'http://www.wikidata.org/entity/Q861690'), ('name', 'West African CFA franc'), ('count', '606963912')]
# [('x', 'http://www.wikidata.org/entity/Q199471'), ('name', 'Afghan afghani'), ('count', '358234802')]
# [('x', 'http://www.wikidata.org/entity/Q41044'), ('name', 'Russian ruble'), ('count', '293715808')]
# [('x', 'http://www.wikidata.org/entity/Q181907'), ('name', 'South African rand'), ('count', '262024610')]
# [('x', 'http://www.wikidata.org/entity/Q847739'), ('name', 'Central African CFA franc'), ('count', '244664546')]
# [('x', 'http://www.wikidata.org/entity/Q259502'), ('name', 'Australian dollar'), ('count', '147961876')]
# [('x', 'http://www.wikidata.org/entity/Q25417'), ('name', 'Danish krone'), ('count', '94084876')]
# [('x', 'http://www.wikidata.org/entity/Q1472704'), ('name', 'New Zealand dollar'), ('count', '40974584')]
# [('x', 'http://www.wikidata.org/entity/Q191068'), ('name', 'Faroese króna'), ('count', '35690230')]
# [('x', 'http://www.wikidata.org/entity/Q25344'), ('name', 'Swiss franc'), ('count', '34015756')]
# [('x', 'http://www.wikidata.org/entity/Q130498'), ('name', 'Armenian dram'), ('count', '6154100')]
# [('x', 'http://www.wikidata.org/entity/Q26365'), ('name', 'Eastern Caribbean dollar'), ('count', '4874934')]
# 18

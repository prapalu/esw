# %% [markdown]
# # General instructions
#
# The goal of the project is to materialize a set of **exploratory workloads** over a real-world, large-scale,  open-domain KG: [WikiData](https://www.wikidata.org/wiki/Wikidata:Main_Page)
#
# An exploratory workload  is composed by a set of queries, where each query is related to the information obtained previously.
#
# An exploratory workload starts with a usually vague, open ended question, and does not assume the person issuing the workload has a clear understanding of the data contained in the target database or its structure.
#
# Remeber that:
#
# 1. All the queries must run in the python notebook
# 2. You can use classes and properties only if you find them via a SPARQL query that must be present in the notebook
# 3. You do not delete useless queries. Keep everything that is synthatically valid
#
# ```
# ?p <http://schema.org/name> ?name .
# ```
#
#     is the BGP returning a human-readable name of a property or a class in Wikidata.

# %%
## SETUP used later

from SPARQLWrapper import SPARQLWrapper, JSON


prefixString = """
##-history6-##
PREFIX wd: <http://www.wikidata.org/entity/> 
PREFIX wdt: <http://www.wikidata.org/prop/direct/> 
PREFIX sc: <http://schema.org/>
"""

# select and construct queries
def run_query(queryString,verbose = True):
    to_run = prefixString + "\n" + queryString

    sparql = SPARQLWrapper("http://a256-gc1-02.srv.aau.dk:5820/sparql")
    sparql.setTimeout(300)
    sparql.setReturnFormat(JSON)
    sparql.setQuery(to_run)

    try :
        results = sparql.query()
        json_results = results.convert()
        if len(json_results['results']['bindings'])==0:
            print("Empty")
            return []
        array = []
        for bindings in json_results['results']['bindings']:
            app =  [ (var, value['value'])  for var, value in bindings.items() ] 
            if verbose:
                print( app)
            array.append(app)
        if verbose:
            print(len(array))
        return array

    except Exception as e :
        print("The operation failed", e)
    
# ASk queries
def run_ask_query(queryString):
    to_run = prefixString + "\n" + queryString

    sparql = SPARQLWrapper("http://a256-gc1-02.srv.aau.dk:5820/sparql")
    sparql.setTimeout(300)
    sparql.setReturnFormat(JSON)
    sparql.setQuery(to_run)

    try :
        return sparql.query().convert()

    except Exception as e :
        print("The operation failed", e)

# %% [markdown]
# # History Workflow Series ("Literary Movements explorative search")
#
# Consider the following exploratory information need:
#
# > investigate the literary movements and the poets. In particular, compare some italian poets in terms of place of birth, number of literary works and education.

# %% [markdown]
# ## Useful URIs for the current workflow
# The following are given:
#
# | IRI           | Description   | Role      |
# | -----------   | -----------   |-----------|
# | `wdt:P1647`   | subproperty   | predicate |
# | `wdt:P31`     | instance of   | predicate |
# | `wdt:P106`    | occupation    | predicate |
# | `wdt:P279`    | subclass      | predicate |
# | `wdt:P27`     | nationality   | predicate |
# | `wdt:P3342`     | Significant person       | predicate |
# | `wd:Q5`| Human       | node |
# | `wd:Q40185`| The Divine Comedy  | node |

# %% [markdown]
# Also consider
#
# ```
# wd:Q40185 ?p ?obj .
# ```
#
# is the BGP to retrieve all **properties of The Divine Comedy**
#
# Please consider that when you return a resource, you should return the IRI and the label of the resource. In particular, when the task require you to identify a BGP the result set must always be a list of couples IRI - label.
#
# The workload should:
#
# 1. Who wrote The Divine Comedy? (return the IRI and the label of the author)
#
# 2. Identify the BGP for poet
#
# 3. Identify the BGP for literary movement
#
# 4. Return the poets born in the same place of the author of The Divine Comedy who are born between 1300 and 1500 (1300 and 1500 included) (the result set must be a list of couples poets IRI and label).
#
# 5. Identify the BGP for literary work
#
# 6. Compare the author of The Divine Comedy with Giovanni Boccaccio. Return for these poets the number of literary work they wrote (the result set must be two triples -one for each author- author IRI, label and #literary work).
#
# 7. Consider italian poets, their place of birth (the city) and their university education. Return for each city the number of poets who born there and who was educated there (the result set must be a list of triples city IRI, label and #poets).
#
# 8. Return the italian poets who won the Nobel Prize in Literature (the result set must be poet IRI and label).

# %% [markdown]
# ## Task 1

# %%
# look at the properties of The Divine Comedy
queryString = """
SELECT  DISTINCT ?prop ?name 
WHERE {
    wd:Q40185 ?prop ?obj .
    # ?prop sc:name ?name.
}
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('prop', 'http://www.wikidata.org/prop/direct/P2551'), ('name', 'used metre')]
# [('prop', 'http://www.wikidata.org/prop/direct/P1273'), ('name', 'CANTIC ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P1296'), ('name', 'Gran Enciclopèdia Catalana ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P1343'), ('name', 'described by source')]
# [('prop', 'http://www.wikidata.org/prop/direct/P136'), ('name', 'genre')]
# [('prop', 'http://www.wikidata.org/prop/direct/P1417'), ('name', 'Encyclopædia Britannica Online ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P18'), ('name', 'image')]
# [('prop', 'http://www.wikidata.org/prop/direct/P1889'), ('name', 'different from')]
# [('prop', 'http://www.wikidata.org/prop/direct/P214'), ('name', 'VIAF ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P227'), ('name', 'GND ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P244'), ('name', 'Library of Congress authority ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P268'), ('name', 'Bibliothèque nationale de France ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P269'), ('name', 'IdRef ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P31'), ('name', 'instance of')]
# [('prop', 'http://www.wikidata.org/prop/direct/P3219'), ('name', 'Encyclopædia Universalis ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P3417'), ('name', 'Quora topic ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P373'), ('name', 'Commons category')]
# [('prop', 'http://www.wikidata.org/prop/direct/P407'), ('name', 'language of work or name')]
# [('prop', 'http://www.wikidata.org/prop/direct/P409'), ('name', 'Libraries Australia ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P435'), ('name', 'MusicBrainz work ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P50'), ('name', 'author')]
# [('prop', 'http://www.wikidata.org/prop/direct/P5063'), ('name', 'Interlingual Index ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P527'), ('name', 'has part')]
# [('prop', 'http://www.wikidata.org/prop/direct/P571'), ('name', 'inception')]
# [('prop', 'http://www.wikidata.org/prop/direct/P5986'), ('name', 'Getty Iconography Authority ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P646'), ('name', 'Freebase ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P674'), ('name', 'characters')]
# [('prop', 'http://www.wikidata.org/prop/direct/P6839'), ('name', 'TV Tropes identifier')]
# [('prop', 'http://www.wikidata.org/prop/direct/P691'), ('name', 'NKCR AUT ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P7314'), ('name', 'TDV İslam Ansiklopedisi ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P747'), ('name', 'has edition or translation')]
# [('prop', 'http://www.wikidata.org/prop/direct/P8189'), ('name', 'National Library of Israel J9U ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P8248'), ('name', 'Colon Classification')]
# [('prop', 'http://www.wikidata.org/prop/direct/P8408'), ('name', 'KBpedia ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P8885'), ('name', 'Namuwiki ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P906'), ('name', 'SELIBR ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P910'), ('name', "topic's main category")]
# [('prop', 'http://www.wikidata.org/prop/direct/P9223'), ('name', 'Provenio UUID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P9322'), ('name', 'SVKKL authority ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P949'), ('name', 'National Library of Israel ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P950'), ('name', 'Biblioteca Nacional de España ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P1274'), ('name', 'ISFDB title ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P6175'), ('name', 'Bitraga work ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P8359'), ('name', 'Dewey Decimal Classification (works and editions)')]
# [('prop', 'http://www.wikidata.org/prop/direct/P2034'), ('name', 'Project Gutenberg ebook ID')]
# [('prop', 'http://www.wikidata.org/prop/direct/P3976'), ('name', 'BVMC work ID')]
# 46

# %%
# look at the properties of The Divine Comedy
queryString = """
SELECT  DISTINCT ?obj ?name 
WHERE {
    wd:Q40185 wdt:P50 ?obj .
    # ?obj sc:name ?name.
}
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('obj', 'http://www.wikidata.org/entity/Q1067'), ('name', 'Dante Alighieri')]
# 1

# %% [markdown]
# ## Task 2

# %%
# look at the properties of The Divine Comedy
queryString = """
SELECT  DISTINCT ?obj ?name 
WHERE {
    wd:Q1067 wdt:P106 ?obj .
    # ?obj sc:name ?name.
}
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('obj', 'http://www.wikidata.org/entity/Q12144794'), ('name', 'prosaist')]
# [('obj', 'http://www.wikidata.org/entity/Q15994177'), ('name', 'political theorist')]
# [('obj', 'http://www.wikidata.org/entity/Q36180'), ('name', 'writer')]
# [('obj', 'http://www.wikidata.org/entity/Q482980'), ('name', 'author')]
# [('obj', 'http://www.wikidata.org/entity/Q4964182'), ('name', 'philosopher')]
# [('obj', 'http://www.wikidata.org/entity/Q49757'), ('name', 'poet')]
# [('obj', 'http://www.wikidata.org/entity/Q822146'), ('name', 'lyricist')]
# [('obj', 'http://www.wikidata.org/entity/Q82955'), ('name', 'politician')]
# [('obj', 'http://www.wikidata.org/entity/Q58968'), ('name', 'intellectual')]
# 9

# %% [markdown]
# ## Task 3

# %%
# look at the properties of Dante
queryString = """
SELECT  DISTINCT ?pr ?name 
WHERE {
    wd:Q1067 ?pr ?obj .
    # ?pr sc:name ?name.
    FILTER(!isLiteral(?obj)).
}
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('pr', 'http://www.wikidata.org/prop/direct/P101'), ('name', 'field of work')]
# [('pr', 'http://www.wikidata.org/prop/direct/P103'), ('name', 'native language')]
# [('pr', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('pr', 'http://www.wikidata.org/prop/direct/P1066'), ('name', 'student of')]
# [('pr', 'http://www.wikidata.org/prop/direct/P119'), ('name', 'place of burial')]
# [('pr', 'http://www.wikidata.org/prop/direct/P1196'), ('name', 'manner of death')]
# [('pr', 'http://www.wikidata.org/prop/direct/P1299'), ('name', 'depicted by')]
# [('pr', 'http://www.wikidata.org/prop/direct/P1343'), ('name', 'described by source')]
# [('pr', 'http://www.wikidata.org/prop/direct/P135'), ('name', 'movement')]
# [('pr', 'http://www.wikidata.org/prop/direct/P140'), ('name', 'religion')]
# [('pr', 'http://www.wikidata.org/prop/direct/P1412'), ('name', 'languages spoken, written or signed')]
# [('pr', 'http://www.wikidata.org/prop/direct/P172'), ('name', 'ethnic group')]
# [('pr', 'http://www.wikidata.org/prop/direct/P18'), ('name', 'image')]
# [('pr', 'http://www.wikidata.org/prop/direct/P19'), ('name', 'place of birth')]
# [('pr', 'http://www.wikidata.org/prop/direct/P20'), ('name', 'place of death')]
# [('pr', 'http://www.wikidata.org/prop/direct/P21'), ('name', 'sex or gender')]
# [('pr', 'http://www.wikidata.org/prop/direct/P22'), ('name', 'father')]
# [('pr', 'http://www.wikidata.org/prop/direct/P25'), ('name', 'mother')]
# [('pr', 'http://www.wikidata.org/prop/direct/P26'), ('name', 'spouse')]
# [('pr', 'http://www.wikidata.org/prop/direct/P27'), ('name', 'country of citizenship')]
# [('pr', 'http://www.wikidata.org/prop/direct/P31'), ('name', 'instance of')]
# [('pr', 'http://www.wikidata.org/prop/direct/P3373'), ('name', 'sibling')]
# [('pr', 'http://www.wikidata.org/prop/direct/P40'), ('name', 'child')]
# [('pr', 'http://www.wikidata.org/prop/direct/P437'), ('name', 'distribution format')]
# [('pr', 'http://www.wikidata.org/prop/direct/P463'), ('name', 'member of')]
# [('pr', 'http://www.wikidata.org/prop/direct/P5008'), ('name', 'on focus list of Wikimedia project')]
# [('pr', 'http://www.wikidata.org/prop/direct/P509'), ('name', 'cause of death')]
# [('pr', 'http://www.wikidata.org/prop/direct/P53'), ('name', 'family')]
# [('pr', 'http://www.wikidata.org/prop/direct/P551'), ('name', 'residence')]
# [('pr', 'http://www.wikidata.org/prop/direct/P607'), ('name', 'conflict')]
# [('pr', 'http://www.wikidata.org/prop/direct/P611'), ('name', 'religious order')]
# [('pr', 'http://www.wikidata.org/prop/direct/P6379'), ('name', 'has works in the collection')]
# [('pr', 'http://www.wikidata.org/prop/direct/P6886'), ('name', 'writing language')]
# [('pr', 'http://www.wikidata.org/prop/direct/P734'), ('name', 'family name')]
# [('pr', 'http://www.wikidata.org/prop/direct/P735'), ('name', 'given name')]
# [('pr', 'http://www.wikidata.org/prop/direct/P737'), ('name', 'influenced by')]
# [('pr', 'http://www.wikidata.org/prop/direct/P7763'), ('name', 'copyright status as a creator')]
# [('pr', 'http://www.wikidata.org/prop/direct/P800'), ('name', 'notable work')]
# [('pr', 'http://www.wikidata.org/prop/direct/P8625'), ('name', 'bibliography')]
# [('pr', 'http://www.wikidata.org/prop/direct/P910'), ('name', "topic's main category")]
# 40

# %%
# look at the properties of Dante
queryString = """
SELECT  DISTINCT ?obj ?name 
WHERE {
    wd:Q1067 wdt:P135 ?obj .
    # ?obj sc:name ?name.
}
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('obj', 'http://www.wikidata.org/entity/Q542036'), ('name', 'Dolce Stil Novo')]
# 1

# %%
# look at the properties of Dante
queryString = """
SELECT  DISTINCT ?class ?name 
WHERE {
    wd:Q1067 wdt:P135 ?obj .
    # ?obj wdt:P31 ?class.
    # ?class sc:name ?name.
}
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('class', 'http://www.wikidata.org/entity/Q3326717'), ('name', 'literary movement')]
# 1

# %% [markdown]
# `Q3326717`-> literary movement

# %% [markdown]
# ## Task 4

# %%
# look at the properties of The Divine Comedy
queryString = """
SELECT  DISTINCT ?o ?name 
WHERE {
    wd:Q1067 wdt:P19 ?o.
    # ?o sc:name ?name.
}
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('o', 'http://www.wikidata.org/entity/Q2044'), ('name', 'Florence')]
# 1

# %%
# look at the properties of The Divine Comedy
queryString = """
SELECT  DISTINCT ?pr ?name 
WHERE {
    wd:Q1067 ?pr ?o.
    # ?pr sc:name ?name.
    FILTER(REGEX(?name, "date")).
}
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('pr', 'http://www.wikidata.org/prop/direct/P569'), ('name', 'date of birth')]
# [('pr', 'http://www.wikidata.org/prop/direct/P570'), ('name', 'date of death')]
# [('pr', 'http://www.wikidata.org/prop/direct/P8440'), ('name', 'Personendatenbank Germania Sacra ID')]
# 3

# %%
# look at the properties of The Divine Comedy
queryString = """
SELECT  DISTINCT ?poet ?name
WHERE {
    wd:Q1067 wdt:P570 ?dDeath.
    wd:Q1067 wdt:P569 ?dBirth.
    # ?poet wdt:P19 wd:Q2044;
        wdt:P569 ?birth;
        wdt:P106 wd:Q49757.
    # ?poet sc:name ?name.
    FILTER((year(?birth) > 1300) && (year(?birth) < 1500)).
}
"""
 
print("Results")
x=run_query(queryString)
# Out:
# Results
# [('poet', 'http://www.wikidata.org/entity/Q21003797'), ('name', 'Michel Verin')]
# [('poet', 'http://www.wikidata.org/entity/Q1248954'), ('name', 'Giovanni di Bernardo Rucellai')]
# [('poet', 'http://www.wikidata.org/entity/Q177854'), ('name', "Lorenzo de' Medici")]
# [('poet', 'http://www.wikidata.org/entity/Q328117'), ('name', 'Girolamo Benivieni')]
# [('poet', 'http://www.wikidata.org/entity/Q721846'), ('name', 'Luigi Alamanni')]
# [('poet', 'http://www.wikidata.org/entity/Q1399'), ('name', 'Niccolò Machiavelli')]
# [('poet', 'http://www.wikidata.org/entity/Q366499'), ('name', 'Orcagna')]
# [('poet', 'http://www.wikidata.org/entity/Q1402'), ('name', 'Giovanni Boccaccio')]
# [('poet', 'http://www.wikidata.org/entity/Q631635'), ('name', 'Luigi Pulci')]
# [('poet', 'http://www.wikidata.org/entity/Q2857170'), ('name', 'Antonio Alamanni')]
# [('poet', 'http://www.wikidata.org/entity/Q1527917'), ('name', 'Giuliano Dati')]
# [('poet', 'http://www.wikidata.org/entity/Q45539848'), ('name', 'Niccolò Tinucci')]
# [('poet', 'http://www.wikidata.org/entity/Q1113645'), ('name', 'Lucrezia Tornabuoni')]
# [('poet', 'http://www.wikidata.org/entity/Q711964'), ('name', 'Cristoforo Landino')]
# [('poet', 'http://www.wikidata.org/entity/Q741841'), ('name', 'Ugolino di Vieri')]
# [('poet', 'http://www.wikidata.org/entity/Q3677259'), ('name', 'Cino Rinuccini')]
# [('poet', 'http://www.wikidata.org/entity/Q640594'), ('name', 'John Dominici')]
# [('poet', 'http://www.wikidata.org/entity/Q781511'), ('name', 'Aurelio Lippo Brandolini')]
# [('poet', 'http://www.wikidata.org/entity/Q13570581'), ('name', 'Bartolomeo della Fonte')]
# [('poet', 'http://www.wikidata.org/entity/Q302218'), ('name', 'Agnolo Firenzuola')]
# [('poet', 'http://www.wikidata.org/entity/Q425969'), ('name', 'Bernardo Bellincioni')]
# [('poet', 'http://www.wikidata.org/entity/Q1229872'), ('name', 'Matteo Palmieri')]
# [('poet', 'http://www.wikidata.org/entity/Q589545'), ('name', 'Bernardo Pulci')]
# [('poet', 'http://www.wikidata.org/entity/Q1215784'), ('name', 'Alessandra Scala')]
# [('poet', 'http://www.wikidata.org/entity/Q659093'), ('name', 'Benedetto Dei')]
# [('poet', 'http://www.wikidata.org/entity/Q50399164'), ('name', "Dolcibene de' Tori")]
# [('poet', 'http://www.wikidata.org/entity/Q3830353'), ('name', 'Leonardo Dati')]
# [('poet', 'http://www.wikidata.org/entity/Q66809563'), ('name', "Alessandro Pazzi de' Medici")]
# [('poet', 'http://www.wikidata.org/entity/Q604448'), ('name', 'Antonio Pucci')]
# [('poet', 'http://www.wikidata.org/entity/Q2832756'), ('name', 'Alessandro Braccesi')]
# [('poet', 'http://www.wikidata.org/entity/Q3750836'), ('name', "Francesco d'Altobianco Alberti")]
# [('poet', 'http://www.wikidata.org/entity/Q1058842'), ('name', 'Domenico di Giovanni')]
# [('poet', 'http://www.wikidata.org/entity/Q1158784'), ('name', 'Crinitus')]
# [('poet', 'http://www.wikidata.org/entity/Q17166727'), ('name', 'Antonio di Meglio')]
# [('poet', 'http://www.wikidata.org/entity/Q3339583'), ('name', 'Niccolò Martelli')]
# [('poet', 'http://www.wikidata.org/entity/Q3068447'), ('name', 'Feo Belcari')]
# [('poet', 'http://www.wikidata.org/entity/Q18945288'), ('name', 'Francesco da Firenze')]
# 37

# %% [markdown]
# ## Task 5

# %%
# look at the properties of Dante
queryString = """
SELECT  DISTINCT ?inst ?name 
WHERE {
    # ?x wdt:P50 wd:Q1402.
    # ?x wdt:P31 ?inst.
    # ?inst sc:name ?name.
}
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('inst', 'http://www.wikidata.org/entity/Q1787111'), ('name', 'biographical dictionary')]
# [('inst', 'http://www.wikidata.org/entity/Q47461344'), ('name', 'written work')]
# [('inst', 'http://www.wikidata.org/entity/Q482'), ('name', 'poetry')]
# [('inst', 'http://www.wikidata.org/entity/Q7725634'), ('name', 'literary work')]
# [('inst', 'http://www.wikidata.org/entity/Q3331189'), ('name', 'version, edition, or translation')]
# [('inst', 'http://www.wikidata.org/entity/Q49084'), ('name', 'short story')]
# [('inst', 'http://www.wikidata.org/entity/Q1980247'), ('name', 'chapter')]
# [('inst', 'http://www.wikidata.org/entity/Q5185279'), ('name', 'poem')]
# [('inst', 'http://www.wikidata.org/entity/Q1279564'), ('name', 'short story collection')]
# [('inst', 'http://www.wikidata.org/entity/Q39811647'), ('name', 'translated work')]
# [('inst', 'http://www.wikidata.org/entity/Q43303440'), ('name', 'novella in the Decameron')]
# [('inst', 'http://www.wikidata.org/entity/Q30749496'), ('name', 'diploma thesis')]
# [('inst', 'http://www.wikidata.org/entity/Q16537202'), ('name', 'list of literary works')]
# 13

# %% [markdown]
# ## Task 6

# %%
# look at the properties of Dante
queryString = """
SELECT ?poets ?name  COUNT(?x) 
WHERE {
    VALUES ?poets {wd:Q1402 wd:Q1067}.
    # ?x wdt:P50 ?poets.
    # ?x wdt:P31 wd:Q7725634.
    # ?poets sc:name ?name.
}
GROUP BY ?poets ?name
"""

print("Results")
x=run_query(queryString)
# Out:
# Results
# [('poets', 'http://www.wikidata.org/entity/Q1402'), ('name', 'Giovanni Boccaccio'), ('callret-2', '10')]
# [('poets', 'http://www.wikidata.org/entity/Q1067'), ('name', 'Dante Alighieri'), ('callret-2', '37')]
# 2

# %% [markdown]
# ## Task 7

# %%
# look at the properties of The Divine Comedy
queryString = """
SELECT  DISTINCT ?pr ?name
WHERE {
    # ?poet wdt:P106 wd:Q49757;
        # ?pr ?o.
    # ?pr sc:name ?name.
    FILTER(!isLiteral(?o)).
}
"""
 
print("Results")
x=run_query(queryString)
# Out:
# Results
# [('pr', 'http://www.wikidata.org/prop/direct/P103'), ('name', 'native language')]
# [('pr', 'http://www.wikidata.org/prop/direct/P1038'), ('name', 'relative')]
# [('pr', 'http://www.wikidata.org/prop/direct/P1050'), ('name', 'medical condition')]
# [('pr', 'http://www.wikidata.org/prop/direct/P106'), ('name', 'occupation')]
# [('pr', 'http://www.wikidata.org/prop/direct/P1066'), ('name', 'student of')]
# [('pr', 'http://www.wikidata.org/prop/direct/P108'), ('name', 'employer')]
# [('pr', 'http://www.wikidata.org/prop/direct/P109'), ('name', 'signature')]
# [('pr', 'http://www.wikidata.org/prop/direct/P119'), ('name', 'place of burial')]
# [('pr', 'http://www.wikidata.org/prop/direct/P1196'), ('name', 'manner of death')]
# [('pr', 'http://www.wikidata.org/prop/direct/P1299'), ('name', 'depicted by')]
# [('pr', 'http://www.wikidata.org/prop/direct/P1303'), ('name', 'instrument')]
# [('pr', 'http://www.wikidata.org/prop/direct/P1343'), ('name', 'described by source')]
# [('pr', 'http://www.wikidata.org/prop/direct/P136'), ('name', 'genre')]
# [('pr', 'http://www.wikidata.org/prop/direct/P140'), ('name', 'religion')]
# [('pr', 'http://www.wikidata.org/prop/direct/P1411'), ('name', 'nominated for')]
# [('pr', 'http://www.wikidata.org/prop/direct/P1412'), ('name', 'languages spoken, written or signed')]
# [('pr', 'http://www.wikidata.org/prop/direct/P1442'), ('name', 'image of grave')]
# [('pr', 'http://www.wikidata.org/prop/direct/P166'), ('name', 'award received')]
# [('pr', 'http://www.wikidata.org/prop/direct/P172'), ('name', 'ethnic group')]
# [('pr', 'http://www.wikidata.org/prop/direct/P18'), ('name', 'image')]
# [('pr', 'http://www.wikidata.org/prop/direct/P1801'), ('name', 'commemorative plaque image')]
# [('pr', 'http://www.wikidata.org/prop/direct/P19'), ('name', 'place of birth')]
# [('pr', 'http://www.wikidata.org/prop/direct/P1950'), ('name', 'second family name in Spanish name')]
# [('pr', 'http://www.wikidata.org/prop/direct/P20'), ('name', 'place of death')]
# [('pr', 'http://www.wikidata.org/prop/direct/P21'), ('name', 'sex or gender')]
# [('pr', 'http://www.wikidata.org/prop/direct/P22'), ('name', 'father')]
# [('pr', 'http://www.wikidata.org/prop/direct/P26'), ('name', 'spouse')]
# [('pr', 'http://www.wikidata.org/prop/direct/P2632'), ('name', 'place of detention')]
# [('pr', 'http://www.wikidata.org/prop/direct/P264'), ('name', 'record label')]
# [('pr', 'http://www.wikidata.org/prop/direct/P27'), ('name', 'country of citizenship')]
# [('pr', 'http://www.wikidata.org/prop/direct/P2868'), ('name', 'subject has role')]
# [('pr', 'http://www.wikidata.org/prop/direct/P31'), ('name', 'instance of')]
# [('pr', 'http://www.wikidata.org/prop/direct/P3373'), ('name', 'sibling')]
# [('pr', 'http://www.wikidata.org/prop/direct/P361'), ('name', 'part of')]
# [('pr', 'http://www.wikidata.org/prop/direct/P39'), ('name', 'position held')]
# [('pr', 'http://www.wikidata.org/prop/direct/P40'), ('name', 'child')]
# [('pr', 'http://www.wikidata.org/prop/direct/P463'), ('name', 'member of')]
# [('pr', 'http://www.wikidata.org/prop/direct/P485'), ('name', 'archives at')]
# [('pr', 'http://www.wikidata.org/prop/direct/P5008'), ('name', 'on focus list of Wikimedia project')]
# [('pr', 'http://www.wikidata.org/prop/direct/P509'), ('name', 'cause of death')]
# [('pr', 'http://www.wikidata.org/prop/direct/P512'), ('name', 'academic degree')]
# [('pr', 'http://www.wikidata.org/prop/direct/P53'), ('name', 'family')]
# [('pr', 'http://www.wikidata.org/prop/direct/P551'), ('name', 'residence')]
# [('pr', 'http://www.wikidata.org/prop/direct/P570'), ('name', 'date of death')]
# [('pr', 'http://www.wikidata.org/prop/direct/P6104'), ('name', 'maintained by WikiProject')]
# [('pr', 'http://www.wikidata.org/prop/direct/P611'), ('name', 'religious order')]
# [('pr', 'http://www.wikidata.org/prop/direct/P6886'), ('name', 'writing language')]
# [('pr', 'http://www.wikidata.org/prop/direct/P69'), ('name', 'educated at')]
# [('pr', 'http://www.wikidata.org/prop/direct/P7084'), ('name', 'related category')]
# [('pr', 'http://www.wikidata.org/prop/direct/P734'), ('name', 'family name')]
# [('pr', 'http://www.wikidata.org/prop/direct/P735'), ('name', 'given name')]
# [('pr', 'http://www.wikidata.org/prop/direct/P7763'), ('name', 'copyright status as a creator')]
# [('pr', 'http://www.wikidata.org/prop/direct/P800'), ('name', 'notable work')]
# [('pr', 'http://www.wikidata.org/prop/direct/P856'), ('name', 'official website')]
# [('pr', 'http://www.wikidata.org/prop/direct/P910'), ('name', "topic's main category")]
# [('pr', 'http://www.wikidata.org/prop/direct/P937'), ('name', 'work location')]
# [('pr', 'http://www.wikidata.org/prop/direct/P973'), ('name', 'described at URL')]
# [('pr', 'http://www.wikidata.org/prop/direct/P470'), ('name', 'Eight Banner register')]
# [('pr', 'http://www.wikidata.org/prop/direct/P101'), ('name', 'field of work')]
# [('pr', 'http://www.wikidata.org/prop/direct/P102'), ('name', 'member of political party')]
# [('pr', 'http://www.wikidata.org/prop/direct/P135'), ('name', 'movement')]
# [('pr', 'http://www.wikidata.org/prop/direct/P1581'), ('name', 'official blog')]
# [('pr', 'http://www.wikidata.org/prop/direct/P1889'), ('name', 'different from')]
# [('pr', 'http://www.wikidata.org/prop/direct/P2348'), ('name', 'time period')]
# [('pr', 'http://www.wikidata.org/prop/direct/P25'), ('name', 'mother')]
# [('pr', 'http://www.wikidata.org/prop/direct/P443'), ('name', 'pronunciation audio')]
# [('pr', 'http://www.wikidata.org/prop/direct/P6275'), ('name', 'copyright representative')]
# [('pr', 'http://www.wikidata.org/prop/direct/P6379'), ('name', 'has works in the collection')]
# [('pr', 'http://www.wikidata.org/prop/direct/P97'), ('name', 'noble title')]
# [('pr', 'http://www.wikidata.org/prop/direct/P1344'), ('name', 'participant in')]
# [('pr', 'http://www.wikidata.org/prop/direct/P1365'), ('name', 'replaces')]
# [('pr', 'http://www.wikidata.org/prop/direct/P1366'), ('name', 'replaced by')]
# [('pr', 'http://www.wikidata.org/prop/direct/P1576'), ('name', 'lifestyle')]
# [('pr', 'http://www.wikidata.org/prop/direct/P179'), ('name', 'part of the series')]
# [('pr', 'http://www.wikidata.org/prop/direct/P1830'), ('name', 'owner of')]
# [('pr', 'http://www.wikidata.org/prop/direct/P641'), ('name', 'sport')]
# [('pr', 'http://www.wikidata.org/prop/direct/P737'), ('name', 'influenced by')]
# [('pr', 'http://www.wikidata.org/prop/direct/P802'), ('name', 'student')]
# [('pr', 'http://www.wikidata.org/prop/direct/P9493'), ('name', 'artist files at')]
# [('pr', 'http://www.wikidata.org/prop/direct/P2408'), ('name', 'set in period')]
# [('pr', 'http://www.wikidata.org/prop/direct/P1347'), ('name', 'military casualty classification')]
# [('pr', 'http://www.wikidata.org/prop/direct/P241'), ('name', 'military branch')]
# [('pr', 'http://www.wikidata.org/prop/direct/P3342'), ('name', 'significant person')]
# [('pr', 'http://www.wikidata.org/prop/direct/P3602'), ('name', 'candidacy in election')]
# [('pr', 'http://www.wikidata.org/prop/direct/P410'), ('name', 'military rank')]
# [('pr', 'http://www.wikidata.org/prop/direct/P412'), ('name', 'voice type')]
# [('pr', 'http://www.wikidata.org/prop/direct/P437'), ('name', 'distribution format')]
# [('pr', 'http://www.wikidata.org/prop/direct/P460'), ('name', 'said to be the same as')]
# [('pr', 'http://www.wikidata.org/prop/direct/P607'), ('name', 'conflict')]
# [('pr', 'http://www.wikidata.org/prop/direct/P747'), ('name', 'has edition or translation')]
# [('pr', 'http://www.wikidata.org/prop/direct/P812'), ('name', 'academic major')]
# [('pr', 'http://www.wikidata.org/prop/direct/P1035'), ('name', 'honorific suffix')]
# [('pr', 'http://www.wikidata.org/prop/direct/P1142'), ('name', 'political ideology')]
# [('pr', 'http://www.wikidata.org/prop/direct/P138'), ('name', 'named after')]
# [('pr', 'http://www.wikidata.org/prop/direct/P184'), ('name', 'doctoral advisor')]
# [('pr', 'http://www.wikidata.org/prop/direct/P569'), ('name', 'date of birth')]
# [('pr', 'http://www.wikidata.org/prop/direct/P793'), ('name', 'significant event')]
# [('pr', 'http://www.wikidata.org/prop/direct/P990'), ('name', "audio recording of the subject's spoken voice")]
# [('pr', 'http://www.wikidata.org/prop/direct/P511'), ('name', 'honorific prefix')]
# [('pr', 'http://www.wikidata.org/prop/direct/P3919'), ('name', 'contributed to creative work')]
# [('pr', 'http://www.wikidata.org/prop/direct/P4004'), ('name', 'escutcheon image')]
# [('pr', 'http://www.wikidata.org/prop/direct/P9419'), ('name', 'personal library at')]
# [('pr', 'http://www.wikidata.org/prop/direct/P1875'), ('name', 'represented by')]
# [('pr', 'http://www.wikidata.org/prop/direct/P2959'), ('name', 'permanent duplicated item')]
# [('pr', 'http://www.wikidata.org/prop/direct/P608'), ('name', 'exhibition history')]
# [('pr', 'http://www.wikidata.org/prop/direct/P803'), ('name', 'professorship')]
# [('pr', 'http://www.wikidata.org/prop/direct/P1399'), ('name', 'convicted of')]
# [('pr', 'http://www.wikidata.org/prop/direct/P1596'), ('name', 'penalty')]
# [('pr', 'http://www.wikidata.org/prop/direct/P94'), ('name', 'coat of arms image')]
# [('pr', 'http://www.wikidata.org/prop/direct/P2358'), ('name', 'Roman praenomen')]
# [('pr', 'http://www.wikidata.org/prop/direct/P2359'), ('name', 'Roman nomen gentilicium')]
# [('pr', 'http://www.wikidata.org/prop/direct/P451'), ('name', 'unmarried partner')]
# [('pr', 'http://www.wikidata.org/prop/direct/P5025'), ('name', 'gens')]
# [('pr', 'http://www.wikidata.org/prop/direct/P91'), ('name', 'sexual orientation')]
# [('pr', 'http://www.wikidata.org/prop/direct/P1416'), ('name', 'affiliation')]
# [('pr', 'http://www.wikidata.org/prop/direct/P1455'), ('name', 'list of works')]
# [('pr', 'http://www.wikidata.org/prop/direct/P2888'), ('name', 'exact match')]
# [('pr', 'http://www.wikidata.org/prop/direct/P1598'), ('name', 'consecrator')]
# [('pr', 'http://www.wikidata.org/prop/direct/P859'), ('name', 'sponsor')]
# [('pr', 'http://www.wikidata.org/prop/direct/P945'), ('name', 'allegiance')]
# [('pr', 'http://www.wikidata.org/prop/direct/P2365'), ('name', 'Roman cognomen')]
# [('pr', 'http://www.wikidata.org/prop/direct/P3716'), ('name', 'social classification')]
# [('pr', 'http://www.wikidata.org/prop/direct/P989'), ('name', 'spoken text audio')]
# [('pr', 'http://www.wikidata.org/prop/direct/P2354'), ('name', 'has list')]
# [('pr', 'http://www.wikidata.org/prop/direct/P411'), ('name', 'canonization status')]
# [('pr', 'http://www.wikidata.org/prop/direct/P5715'), ('name', 'Academia.edu profile URL')]
# [('pr', 'http://www.wikidata.org/prop/direct/P1340'), ('name', 'eye color')]
# [('pr', 'http://www.wikidata.org/prop/direct/P1424'), ('name', "topic's main template")]
# [('pr', 'http://www.wikidata.org/prop/direct/P1884'), ('name', 'hair color')]
# [('pr', 'http://www.wikidata.org/prop/direct/P841'), ('name', 'feast day')]
# [('pr', 'http://www.wikidata.org/prop/direct/P1283'), ('name', 'filmography')]
# [('pr', 'http://www.wikidata.org/prop/direct/P358'), ('name', 'discography')]
# [('pr', 'http://www.wikidata.org/prop/direct/P968'), ('name', 'email address')]
# [('pr', 'http://www.wikidata.org/prop/direct/P1532'), ('name', 'country for sport')]
# [('pr', 'http://www.wikidata.org/prop/direct/P5056'), ('name', 'patronym or matronym for this person')]
# [('pr', 'http://www.wikidata.org/prop/direct/P3448'), ('name', 'stepparent')]
# [('pr', 'http://www.wikidata.org/prop/direct/P9660'), ('name', 'not found in')]
# [('pr', 'http://www.wikidata.org/prop/direct/P185'), ('name', 'doctoral student')]
# [('pr', 'http://www.wikidata.org/prop/direct/P112'), ('name', 'founded by')]
# [('pr', 'http://www.wikidata.org/prop/direct/P1327'), ('name', 'partner in business or sport')]
# [('pr', 'http://www.wikidata.org/prop/direct/P8017'), ('name', 'generational suffix')]
# [('pr', 'http://www.wikidata.org/prop/direct/P6872'), ('name', 'has written for')]
# [('pr', 'http://www.wikidata.org/prop/direct/P767'), ('name', 'contributor to the creative work or subject')]
# [('pr', 'http://www.wikidata.org/prop/direct/P547'), ('name', 'commemorates')]
# [('pr', 'http://www.wikidata.org/prop/direct/P154'), ('name', 'logo image')]
# [('pr', 'http://www.wikidata.org/prop/direct/P2936'), ('name', 'language used')]
# [('pr', 'http://www.wikidata.org/prop/direct/P740'), ('name', 'location of formation')]
# [('pr', 'http://www.wikidata.org/prop/direct/P2699'), ('name', 'URL')]
# [('pr', 'http://www.wikidata.org/prop/direct/P413'), ('name', 'position played on team / speciality')]
# [('pr', 'http://www.wikidata.org/prop/direct/P1853'), ('name', 'blood type')]
# [('pr', 'http://www.wikidata.org/prop/direct/P6802'), ('name', 'related image')]
# [('pr', 'http://www.wikidata.org/prop/direct/P2650'), ('name', 'interested in')]
# [('pr', 'http://www.wikidata.org/prop/direct/P2094'), ('name', 'competition class')]
# [('pr', 'http://www.wikidata.org/prop/direct/P1026'), ('name', 'academic thesis')]
# [('pr', 'http://www.wikidata.org/prop/direct/P6978'), ('name', 'Scandinavian middle family name')]
# [('pr', 'http://www.wikidata.org/prop/direct/P1387'), ('name', 'political alignment')]
# [('pr', 'http://www.wikidata.org/prop/direct/P237'), ('name', 'coat of arms')]
# [('pr', 'http://www.wikidata.org/prop/direct/P6902'), ('name', 'era name')]
# [('pr', 'http://www.wikidata.org/prop/direct/P708'), ('name', 'diocese')]
# [('pr', 'http://www.wikidata.org/prop/direct/P1877'), ('name', 'after a work by')]
# [('pr', 'http://www.wikidata.org/prop/direct/P527'), ('name', 'has part')]
# [('pr', 'http://www.wikidata.org/prop/direct/P51'), ('name', 'audio')]
# [('pr', 'http://www.wikidata.org/prop/direct/P2652'), ('name', 'partnership with')]
# [('pr', 'http://www.wikidata.org/prop/direct/P7779'), ('name', 'member of military unit')]
# [('pr', 'http://www.wikidata.org/prop/direct/P6553'), ('name', 'personal pronoun')]
# [('pr', 'http://www.wikidata.org/prop/direct/P2596'), ('name', 'culture')]
# [('pr', 'http://www.wikidata.org/prop/direct/P941'), ('name', 'inspired by')]
# [('pr', 'http://www.wikidata.org/prop/direct/P1441'), ('name', 'present in work')]
# [('pr', 'http://www.wikidata.org/prop/direct/P825'), ('name', 'dedicated to')]
# [('pr', 'http://www.wikidata.org/prop/direct/P1290'), ('name', 'godparent')]
# [('pr', 'http://www.wikidata.org/prop/direct/P1543'), ('name', 'monogram')]
# [('pr', 'http://www.wikidata.org/prop/direct/P158'), ('name', 'seal image')]
# [('pr', 'http://www.wikidata.org/prop/direct/P248'), ('name', 'stated in')]
# [('pr', 'http://www.wikidata.org/prop/direct/P1037'), ('name', 'director / manager')]
# [('pr', 'http://www.wikidata.org/prop/direct/P1151'), ('name', "topic's main Wikimedia portal")]
# [('pr', 'http://www.wikidata.org/prop/direct/P8625'), ('name', 'bibliography')]
# [('pr', 'http://www.wikidata.org/prop/direct/P8852'), ('name', 'facial hair')]
# [('pr', 'http://www.wikidata.org/prop/direct/P2579'), ('name', 'studied by')]
# [('pr', 'http://www.wikidata.org/prop/direct/P3938'), ('name', 'named by')]
# [('pr', 'http://www.wikidata.org/prop/direct/P66'), ('name', 'ancestral home')]
# [('pr', 'http://www.wikidata.org/prop/direct/P7153'), ('name', 'significant place')]
# [('pr', 'http://www.wikidata.org/prop/direct/P4292'), ('name', 'possessed by spirit')]
# [('pr', 'http://www.wikidata.org/prop/direct/P5021'), ('name', 'assessment')]
# [('pr', 'http://www.wikidata.org/prop/direct/P5012'), ('name', 'special rank')]
# [('pr', 'http://www.wikidata.org/prop/direct/P157'), ('name', 'killed by')]
# [('pr', 'http://www.wikidata.org/prop/direct/P2283'), ('name', 'uses')]
# [('pr', 'http://www.wikidata.org/prop/direct/P552'), ('name', 'handedness')]
# [('pr', 'http://www.wikidata.org/prop/direct/P1433'), ('name', 'published in')]
# [('pr', 'http://www.wikidata.org/prop/direct/P598'), ('name', 'commander of (DEPRECATED)')]
# [('pr', 'http://www.wikidata.org/prop/direct/P8786'), ('name', 'dedicated heritage entity')]
# [('pr', 'http://www.wikidata.org/prop/direct/P2522'), ('name', 'victory')]
# [('pr', 'http://www.wikidata.org/prop/direct/P54'), ('name', 'member of sports team')]
# [('pr', 'http://www.wikidata.org/prop/direct/P741'), ('name', 'playing hand')]
# [('pr', 'http://www.wikidata.org/prop/direct/P1268'), ('name', 'represents')]
# [('pr', 'http://www.wikidata.org/prop/direct/P1429'), ('name', 'has pet')]
# [('pr', 'http://www.wikidata.org/prop/direct/P3095'), ('name', 'practiced by')]
# [('pr', 'http://www.wikidata.org/prop/direct/P4426'), ('name', 'Y-DNA Haplogroup')]
# [('pr', 'http://www.wikidata.org/prop/direct/P2962'), ('name', 'title of chess person')]
# [('pr', 'http://www.wikidata.org/prop/direct/P276'), ('name', 'location')]
# [('pr', 'http://www.wikidata.org/prop/direct/P953'), ('name', 'full work available at URL')]
# [('pr', 'http://www.wikidata.org/prop/direct/P550'), ('name', 'chivalric order')]
# [('pr', 'http://www.wikidata.org/prop/direct/P6758'), ('name', 'supported sports team')]
# [('pr', 'http://www.wikidata.org/prop/direct/P1766'), ('name', 'place name sign')]
# [('pr', 'http://www.wikidata.org/prop/direct/P7781'), ('name', 'exonerated of')]
# [('pr', 'http://www.wikidata.org/prop/direct/P488'), ('name', 'chairperson')]
# [('pr', 'http://www.wikidata.org/prop/direct/P2789'), ('name', 'connects with')]
# [('pr', 'http://www.wikidata.org/prop/direct/P123'), ('name', 'publisher')]
# [('pr', 'http://www.wikidata.org/prop/direct/P8927'), ('name', 'kunya')]
# [('pr', 'http://www.wikidata.org/prop/direct/P3701'), ('name', 'incarnation of')]
# [('pr', 'http://www.wikidata.org/prop/direct/P2184'), ('name', 'history of topic')]
# [('pr', 'http://www.wikidata.org/prop/direct/P8822'), ('name', 'epithet')]
# [('pr', 'http://www.wikidata.org/prop/direct/P2462'), ('name', 'member of the deme')]
# [('pr', 'http://www.wikidata.org/prop/direct/P3205'), ('name', 'patient of')]
# [('pr', 'http://www.wikidata.org/prop/direct/P3438'), ('name', 'vehicle normally used')]
# [('pr', 'http://www.wikidata.org/prop/direct/P948'), ('name', 'page banner')]
# [('pr', 'http://www.wikidata.org/prop/direct/P3828'), ('name', 'wears')]
# [('pr', 'http://www.wikidata.org/prop/direct/P8693'), ('name', 'fandom')]
# [('pr', 'http://www.wikidata.org/prop/direct/P369'), ('name', 'Sandbox-Item')]
# [('pr', 'http://www.wikidata.org/prop/direct/P4185'), ('name', 'iconographic symbol')]
# [('pr', 'http://www.wikidata.org/prop/direct/P2925'), ('name', 'domain of saint or deity')]
# [('pr', 'http://www.wikidata.org/prop/direct/P61'), ('name', 'discoverer or inventor')]
# [('pr', 'http://www.wikidata.org/prop/direct/P8596'), ('name', 'category for the exterior of the item')]
# [('pr', 'http://www.wikidata.org/prop/direct/P9139'), ('name', 'first family name in Portuguese name')]
# [('pr', 'http://www.wikidata.org/prop/direct/P1049'), ('name', 'worshipped by')]
# [('pr', 'http://www.wikidata.org/prop/direct/P9600'), ('name', 'oral history at')]
# [('pr', 'http://www.wikidata.org/prop/direct/P5096'), ('name', 'member of the crew of')]
# [('pr', 'http://www.wikidata.org/prop/direct/P1165'), ('name', 'home world')]
# [('pr', 'http://www.wikidata.org/prop/direct/P1080'), ('name', 'from narrative universe')]
# [('pr', 'http://www.wikidata.org/prop/direct/P170'), ('name', 'creator')]
# [('pr', 'http://www.wikidata.org/prop/direct/P175'), ('name', 'performer')]
# [('pr', 'http://www.wikidata.org/prop/direct/P4969'), ('name', 'derivative work')]
# [('pr', 'http://www.wikidata.org/prop/direct/P7047'), ('name', 'enemy of')]
# [('pr', 'http://www.wikidata.org/prop/direct/P8345'), ('name', 'media franchise')]
# [('pr', 'http://www.wikidata.org/prop/direct/P85'), ('name', 'anthem')]
# [('pr', 'http://www.wikidata.org/prop/direct/P553'), ('name', 'website account on')]
# [('pr', 'http://www.wikidata.org/prop/direct/P1731'), ('name', 'Fach')]
# [('pr', 'http://www.wikidata.org/prop/direct/P10'), ('name', 'video')]
# [('pr', 'http://www.wikidata.org/prop/direct/P710'), ('name', 'participant')]
# [('pr', 'http://www.wikidata.org/prop/direct/P1027'), ('name', 'conferred by')]
# [('pr', 'http://www.wikidata.org/prop/direct/P8195'), ('name', 'ex-libris')]
# [('pr', 'http://www.wikidata.org/prop/direct/P1074'), ('name', 'fictional analog of')]
# [('pr', 'http://www.wikidata.org/prop/direct/P1321'), ('name', 'place of origin (Switzerland)')]
# [('pr', 'http://www.wikidata.org/prop/direct/P2366'), ('name', 'Roman agnomen')]
# [('pr', 'http://www.wikidata.org/prop/direct/P5800'), ('name', 'narrative role')]
# [('pr', 'http://www.wikidata.org/prop/direct/P1775'), ('name', 'follower of')]
# [('pr', 'http://www.wikidata.org/prop/direct/P972'), ('name', 'catalog')]
# [('pr', 'http://www.wikidata.org/prop/direct/P407'), ('name', 'language of work or name')]
# [('pr', 'http://www.wikidata.org/prop/direct/P8929'), ('name', 'religion or world view')]
# [('pr', 'http://www.wikidata.org/prop/direct/P2416'), ('name', 'sports discipline competed in')]
# [('pr', 'http://www.wikidata.org/prop/direct/P286'), ('name', 'head coach')]
# [('pr', 'http://www.wikidata.org/prop/direct/P41'), ('name', 'flag image')]
# [('pr', 'http://www.wikidata.org/prop/direct/P4900'), ('name', 'broader concept')]
# [('pr', 'http://www.wikidata.org/prop/direct/P282'), ('name', 'writing system')]
# [('pr', 'http://www.wikidata.org/prop/direct/P156'), ('name', 'followed by')]
# [('pr', 'http://www.wikidata.org/prop/direct/P3150'), ('name', 'birthday')]
# [('pr', 'http://www.wikidata.org/prop/direct/P746'), ('name', 'date of disappearance')]
# [('pr', 'http://www.wikidata.org/prop/direct/P1995'), ('name', 'health specialty')]
# [('pr', 'http://www.wikidata.org/prop/direct/P8413'), ('name', 'academic appointment')]
# [('pr', 'http://www.wikidata.org/prop/direct/P155'), ('name', 'follows')]
# [('pr', 'http://www.wikidata.org/prop/direct/P531'), ('name', 'diplomatic mission sent')]
# [('pr', 'http://www.wikidata.org/prop/direct/P162'), ('name', 'producer')]
# [('pr', 'http://www.wikidata.org/prop/direct/P7937'), ('name', 'form of creative work')]
# [('pr', 'http://www.wikidata.org/prop/direct/P137'), ('name', 'operator')]
# [('pr', 'http://www.wikidata.org/prop/direct/P3259'), ('name', 'intangible cultural heritage status')]
# [('pr', 'http://www.wikidata.org/prop/direct/P36'), ('name', 'capital')]
# [('pr', 'http://www.wikidata.org/prop/direct/P50'), ('name', 'author')]
# [('pr', 'http://www.wikidata.org/prop/direct/P4100'), ('name', 'parliamentary group')]
# [('pr', 'http://www.wikidata.org/prop/direct/P1552'), ('name', 'has quality')]
# [('pr', 'http://www.wikidata.org/prop/direct/P647'), ('name', 'drafted by')]
# [('pr', 'http://www.wikidata.org/prop/direct/P195'), ('name', 'collection')]
# [('pr', 'http://www.wikidata.org/prop/direct/P144'), ('name', 'based on')]
# [('pr', 'http://www.wikidata.org/prop/direct/P3680'), ('name', 'statement supported by')]
# [('pr', 'http://www.wikidata.org/prop/direct/P366'), ('name', 'use')]
# [('pr', 'http://www.wikidata.org/prop/direct/P8500'), ('name', 'Vietnamese middle name')]
# [('pr', 'http://www.wikidata.org/prop/direct/P214'), ('name', 'VIAF ID')]
# [('pr', 'http://www.wikidata.org/prop/direct/P1039'), ('name', 'kinship to subject')]
# [('pr', 'http://www.wikidata.org/prop/direct/P967'), ('name', 'guest of honor')]
# [('pr', 'http://www.wikidata.org/prop/direct/P180'), ('name', 'depicts')]
# [('pr', 'http://www.wikidata.org/prop/direct/P17'), ('name', 'country')]
# [('pr', 'http://www.wikidata.org/prop/direct/P35'), ('name', 'head of state')]
# [('pr', 'http://www.wikidata.org/prop/direct/P2291'), ('name', 'charted in')]
# [('pr', 'http://www.wikidata.org/prop/direct/P98'), ('name', 'editor')]
# [('pr', 'http://www.wikidata.org/prop/direct/P1593'), ('name', 'defender')]
# [('pr', 'http://www.wikidata.org/prop/direct/P2578'), ('name', 'studies')]
# [('pr', 'http://www.wikidata.org/prop/direct/P2813'), ('name', 'house publication')]
# [('pr', 'http://www.wikidata.org/prop/direct/P495'), ('name', 'country of origin')]
# [('pr', 'http://www.wikidata.org/prop/direct/P169'), ('name', 'chief executive officer')]
# [('pr', 'http://www.wikidata.org/prop/direct/P118'), ('name', 'league')]
# [('pr', 'http://www.wikidata.org/prop/direct/P1325'), ('name', 'external data available at')]
# [('pr', 'http://www.wikidata.org/prop/direct/P1264'), ('name', 'valid in period')]
# [('pr', 'http://www.wikidata.org/prop/direct/P1535'), ('name', 'used by')]
# [('pr', 'http://www.wikidata.org/prop/direct/P3075'), ('name', 'official religion')]
# [('pr', 'http://www.wikidata.org/prop/direct/P1317'), ('name', 'floruit')]
# [('pr', 'http://www.wikidata.org/prop/direct/P7569'), ('name', 'Wikimedia page-version URL')]
# [('pr', 'http://www.wikidata.org/prop/direct/P4584'), ('name', 'first appearance')]
# [('pr', 'http://www.wikidata.org/prop/direct/P6107'), ('name', 'winterthur-glossar URL')]
# [('pr', 'http://www.wikidata.org/prop/direct/P161'), ('name', 'cast member')]
# [('pr', 'http://www.wikidata.org/prop/direct/P1346'), ('name', 'winner')]
# [('pr', 'http://www.wikidata.org/prop/direct/P1056'), ('name', 'product or material produced')]
# [('pr', 'http://www.wikidata.org/prop/direct/P1559'), ('name', 'name in native language')]
# [('pr', 'http://www.wikidata.org/prop/direct/P8214'), ('name', 'curriculum vitae')]
# [('pr', 'http://www.wikidata.org/prop/direct/P4444'), ('name', 'reward')]
# [('pr', 'http://www.wikidata.org/prop/direct/P263'), ('name', 'official residence')]
# [('pr', 'http://www.wikidata.org/prop/direct/P2341'), ('name', 'indigenous to')]
# [('pr', 'http://www.wikidata.org/prop/direct/P279'), ('name', 'subclass of')]
# [('pr', 'http://www.wikidata.org/prop/direct/P360'), ('name', 'is a list of')]
# [('pr', 'http://www.wikidata.org/prop/direct/P1419'), ('name', 'shape')]
# [('pr', 'http://www.wikidata.org/prop/direct/P1477'), ('name', 'birth name')]
# [('pr', 'http://www.wikidata.org/prop/direct/P462'), ('name', 'color')]
# [('pr', 'http://www.wikidata.org/prop/direct/P1437'), ('name', 'plea')]
# [('pr', 'http://www.wikidata.org/prop/direct/P291'), ('name', 'place of publication')]
# [('pr', 'http://www.wikidata.org/prop/direct/P991'), ('name', 'successful candidate')]
# [('pr', 'http://www.wikidata.org/prop/direct/P5389'), ('name', 'permanent resident of')]
# [('pr', 'http://www.wikidata.org/prop/direct/P1019'), ('name', 'web feed URL')]
# [('pr', 'http://www.wikidata.org/prop/direct/P1065'), ('name', 'archive URL')]
# [('pr', 'http://www.wikidata.org/prop/direct/P37'), ('name', 'official language')]
# [('pr', 'http://www.wikidata.org/prop/direct/P452'), ('name', 'industry')]
# [('pr', 'http://www.wikidata.org/prop/direct/P1780'), ('name', 'school of')]
# [('pr', 'http://www.wikidata.org/prop/direct/P1269'), ('name', 'facet of')]
# [('pr', 'http://www.wikidata.org/prop/direct/P2716'), ('name', 'collage image')]
# [('pr', 'http://www.wikidata.org/prop/direct/P3091'), ('name', 'mount')]
# [('pr', 'http://www.wikidata.org/prop/direct/P2389'), ('name', 'organization directed by the office or position')]
# [('pr', 'http://www.wikidata.org/prop/direct/P4101'), ('name', 'dissertation submitted to')]
# [('pr', 'http://www.wikidata.org/prop/direct/P1896'), ('name', 'source website for the property')]
# [('pr', 'http://www.wikidata.org/prop/direct/P364'), ('name', 'original language of film or TV show')]
# [('pr', 'http://www.wikidata.org/prop/direct/P57'), ('name', 'director')]
# [('pr', 'http://www.wikidata.org/prop/direct/P86'), ('name', 'composer')]
# [('pr', 'http://www.wikidata.org/prop/direct/P4656'), ('name', 'Wikimedia import URL')]
# [('pr', 'http://www.wikidata.org/prop/direct/P996'), ('name', 'document file on Wikimedia Commons')]
# [('pr', 'http://www.wikidata.org/prop/direct/P466'), ('name', 'occupant')]
# [('pr', 'http://www.wikidata.org/prop/direct/P2031'), ('name', 'work period (start)')]
# [('pr', 'http://www.wikidata.org/prop/direct/P2872'), ('name', 'visitor centre')]
# 332

# %%
# look at the properties of The Divine Comedy
queryString = """
SELECT ?city ?name COUNT(?poet) AS ?poets
WHERE {
    # ?poet wdt:P106 wd:Q49757;
        wdt:P19 ?city;
        wdt:P69 ?o.
    # ?city wdt:P17 wd:Q38.
    # ?o wdt:P131 ?city;
        wdt:P31 wd:Q3918.
    # ?city sc:name ?name.
}
GROUP BY ?city ?name
"""
 
print("Results")
x=run_query(queryString)
# Out:
# Results
# [('city', 'http://www.wikidata.org/entity/Q220'), ('name', 'Rome'), ('poets', '2')]
# [('city', 'http://www.wikidata.org/entity/Q1449'), ('name', 'Genoa'), ('poets', '3')]
# [('city', 'http://www.wikidata.org/entity/Q2634'), ('name', 'Naples'), ('poets', '2')]
# [('city', 'http://www.wikidata.org/entity/Q2751'), ('name', 'Siena'), ('poets', '1')]
# [('city', 'http://www.wikidata.org/entity/Q490'), ('name', 'Milan'), ('poets', '8')]
# [('city', 'http://www.wikidata.org/entity/Q2044'), ('name', 'Florence'), ('poets', '9')]
# [('city', 'http://www.wikidata.org/entity/Q617'), ('name', 'Padua'), ('poets', '4')]
# [('city', 'http://www.wikidata.org/entity/Q13629'), ('name', 'Sassari'), ('poets', '1')]
# [('city', 'http://www.wikidata.org/entity/Q1903'), ('name', 'Catania'), ('poets', '1')]
# [('city', 'http://www.wikidata.org/entity/Q13362'), ('name', 'Ferrara'), ('poets', '1')]
# [('city', 'http://www.wikidata.org/entity/Q495'), ('name', 'Turin'), ('poets', '9')]
# [('city', 'http://www.wikidata.org/entity/Q3519'), ('name', 'Bari'), ('poets', '1')]
# [('city', 'http://www.wikidata.org/entity/Q13666'), ('name', 'Messina'), ('poets', '1')]
# [('city', 'http://www.wikidata.org/entity/Q2759'), ('name', 'Urbino'), ('poets', '2')]
# [('city', 'http://www.wikidata.org/entity/Q2683'), ('name', 'Parma'), ('poets', '1')]
# 15

# %% [markdown]
# ## Task 8

# %%
# look at the properties of The Divine Comedy
queryString = """
SELECT DISTINCT ?aw ?name
WHERE {
    # ?poet wdt:P106 wd:Q49757;
        wdt:P19 ?city.
    # ?city wdt:P17 wd:Q38.
    # ?poet wdt:P166 ?aw.
    # ?aw sc:name ?name.
    filter(REGEX(?name , "Nobel")).
}
"""
 
print("Results")
x=run_query(queryString)
# Out:
# Results
# [('aw', 'http://www.wikidata.org/entity/Q37922'), ('name', 'Nobel Prize in Literature')]
# 1

# %%
# look at the properties of The Divine Comedy
queryString = """
SELECT DISTINCT ?poet ?name
WHERE {
    # ?poet wdt:P106 wd:Q49757;
        wdt:P19 ?city.
    # ?city wdt:P17 wd:Q38.
    # ?poet wdt:P166 wd:Q37922.
    # ?poet sc:name ?name.
}
"""
 
print("Results")
x=run_query(queryString)
# Out:
# Results
# [('poet', 'http://www.wikidata.org/entity/Q7728'), ('name', 'Grazia Deledda')]
# [('poet', 'http://www.wikidata.org/entity/Q43440'), ('name', 'Giosuè Carducci')]
# [('poet', 'http://www.wikidata.org/entity/Q1403'), ('name', 'Luigi Pirandello')]
# [('poet', 'http://www.wikidata.org/entity/Q765'), ('name', 'Dario Fo')]
# [('poet', 'http://www.wikidata.org/entity/Q83038'), ('name', 'Salvatore Quasimodo')]
# [('poet', 'http://www.wikidata.org/entity/Q83174'), ('name', 'Eugenio Montale')]
# 6
